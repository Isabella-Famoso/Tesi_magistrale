# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA (ampiezza dell'intervallo sulle x è +- la metà del seeing) e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     363   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        44   (2094, 964)   float32

# %%
image_cut = image[49:149, 0:1890]
image_error_cut = image_error[49:149, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.04263
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/PSF/Real_seeing_FIRST_1.txt")
sigmas = seeing / 2.35
n_component = 6
print(sigmas)
# Out:
# [1.00391516 1.0803587  1.00353273 1.00194585 1.0715137 ]

# %%
l_HA
# Out:
# 6842.78069

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[49:149, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     363   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        44   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 25)*(y < 35)
mask_wv = wv > 4400
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 51072.74211257182
# differential_evolution step 2: f(x)= 29514.523388372254
# differential_evolution step 3: f(x)= 29514.523388372254
# differential_evolution step 4: f(x)= 29514.523388372254
# differential_evolution step 5: f(x)= 29514.523388372254
# differential_evolution step 6: f(x)= 25000.027327249427
# differential_evolution step 7: f(x)= 18467.078248398408
# differential_evolution step 8: f(x)= 13540.540214617758
# differential_evolution step 9: f(x)= 13540.540214617758
# differential_evolution step 10: f(x)= 13540.540214617758
# differential_evolution step 11: f(x)= 13540.540214617758
# differential_evolution step 12: f(x)= 12723.430163204284
# differential_evolution step 13: f(x)= 12723.430163204284
# differential_evolution step 14: f(x)= 12394.905372543926
# differential_evolution step 15: f(x)= 12394.905372543926
# differential_evolution step 16: f(x)= 12394.905372543926
# differential_evolution step 17: f(x)= 12394.905372543926
# differential_evolution step 18: f(x)= 10958.67325267529
# differential_evolution step 19: f(x)= 10958.67325267529
# differential_evolution step 20: f(x)= 10958.67325267529
# differential_evolution step 21: f(x)= 10958.67325267529
# differential_evolution step 22: f(x)= 10958.67325267529
# differential_evolution step 23: f(x)= 10958.67325267529
# differential_evolution step 24: f(x)= 10958.67325267529
# differential_evolution step 25: f(x)= 10958.67325267529
# differential_evolution step 26: f(x)= 7073.486413281753
# differential_evolution step 27: f(x)= 7073.486413281753
# differential_evolution step 28: f(x)= 7073.486413281753
# differential_evolution step 29: f(x)= 7073.486413281753
# differential_evolution step 30: f(x)= 7073.486413281753
# differential_evolution step 31: f(x)= 7073.486413281753
# differential_evolution step 32: f(x)= 7073.486413281753
# differential_evolution step 33: f(x)= 7073.486413281753
# differential_evolution step 34: f(x)= 7073.486413281753
# differential_evolution step 35: f(x)= 7073.486413281753
# differential_evolution step 36: f(x)= 7073.486413281753
# differential_evolution step 37: f(x)= 4866.352818404385
# differential_evolution step 38: f(x)= 4866.352818404385
# differential_evolution step 39: f(x)= 4866.352818404385
# differential_evolution step 40: f(x)= 4866.352818404385
# differential_evolution step 41: f(x)= 4866.352818404385
# differential_evolution step 42: f(x)= 4866.352818404385
# differential_evolution step 43: f(x)= 4866.352818404385
# differential_evolution step 44: f(x)= 3510.4618571346145
# differential_evolution step 45: f(x)= 3510.4618571346145
# differential_evolution step 46: f(x)= 3510.4618571346145
# differential_evolution step 47: f(x)= 3510.4618571346145
# differential_evolution step 48: f(x)= 3510.4618571346145
# differential_evolution step 49: f(x)= 3510.4618571346145
# differential_evolution step 50: f(x)= 3510.4618571346145
# differential_evolution step 51: f(x)= 3510.4618571346145
# differential_evolution step 52: f(x)= 3510.4618571346145
# differential_evolution step 53: f(x)= 3510.4618571346145
# differential_evolution step 54: f(x)= 3510.4618571346145
# differential_evolution step 55: f(x)= 3510.4618571346145
# differential_evolution step 56: f(x)= 3510.4618571346145
# differential_evolution step 57: f(x)= 3510.4618571346145
# differential_evolution step 58: f(x)= 3510.4618571346145
# differential_evolution step 59: f(x)= 3510.4618571346145
# differential_evolution step 60: f(x)= 3198.219531244476
# differential_evolution step 61: f(x)= 3198.219531244476
# differential_evolution step 62: f(x)= 3198.219531244476
# differential_evolution step 63: f(x)= 2969.3922223429154
# differential_evolution step 64: f(x)= 2969.3922223429154
# differential_evolution step 65: f(x)= 2536.5925579588643
# differential_evolution step 66: f(x)= 2536.5925579588643
# differential_evolution step 67: f(x)= 2288.5603825110943
# differential_evolution step 68: f(x)= 2288.5603825110943
# differential_evolution step 69: f(x)= 2288.5603825110943
# differential_evolution step 70: f(x)= 2246.2971183897444
# differential_evolution step 71: f(x)= 2246.2971183897444
# differential_evolution step 72: f(x)= 1839.0631062429716
# differential_evolution step 73: f(x)= 1839.0631062429716
# differential_evolution step 74: f(x)= 1839.0631062429716
# differential_evolution step 75: f(x)= 1802.6849922343292
# differential_evolution step 76: f(x)= 1802.6849922343292
# differential_evolution step 77: f(x)= 1802.6849922343292
# differential_evolution step 78: f(x)= 1565.1478626323146
# differential_evolution step 79: f(x)= 1565.1478626323146
# differential_evolution step 80: f(x)= 1565.1478626323146
# differential_evolution step 81: f(x)= 1230.7984535402095
# differential_evolution step 82: f(x)= 1095.4308036377522
# differential_evolution step 83: f(x)= 1095.4308036377522
# differential_evolution step 84: f(x)= 1095.4308036377522
# differential_evolution step 85: f(x)= 1095.4308036377522
# differential_evolution step 86: f(x)= 1095.4308036377522
# differential_evolution step 87: f(x)= 1095.4308036377522
# differential_evolution step 88: f(x)= 969.5317793186957
# differential_evolution step 89: f(x)= 969.5317793186957
# differential_evolution step 90: f(x)= 969.5317793186957
# differential_evolution step 91: f(x)= 969.5317793186957
# differential_evolution step 92: f(x)= 969.5317793186957
# differential_evolution step 93: f(x)= 969.5317793186957
# differential_evolution step 94: f(x)= 969.5317793186957
# differential_evolution step 95: f(x)= 969.5317793186957
# differential_evolution step 96: f(x)= 958.0093814103624
# differential_evolution step 97: f(x)= 958.0093814103624
# differential_evolution step 98: f(x)= 958.0093814103624
# differential_evolution step 99: f(x)= 958.0093814103624
# differential_evolution step 100: f(x)= 958.0093814103624
# differential_evolution step 101: f(x)= 958.0093814103624
# differential_evolution step 102: f(x)= 958.0093814103624
# differential_evolution step 103: f(x)= 958.0093814103624
# differential_evolution step 104: f(x)= 958.0093814103624
# differential_evolution step 105: f(x)= 958.0093814103624
# differential_evolution step 106: f(x)= 958.0093814103624
# differential_evolution step 107: f(x)= 958.0093814103624
# differential_evolution step 108: f(x)= 958.0093814103624
# differential_evolution step 109: f(x)= 815.9548642405791
# differential_evolution step 110: f(x)= 815.9548642405791
# differential_evolution step 111: f(x)= 758.5769928562197
# differential_evolution step 112: f(x)= 758.5769928562197
# differential_evolution step 113: f(x)= 758.5769928562197
# differential_evolution step 114: f(x)= 758.5769928562197
# differential_evolution step 115: f(x)= 758.5769928562197
# differential_evolution step 116: f(x)= 758.5769928562197
# differential_evolution step 117: f(x)= 758.5769928562197
# differential_evolution step 118: f(x)= 758.5769928562197
# differential_evolution step 119: f(x)= 758.5769928562197
# differential_evolution step 120: f(x)= 758.5769928562197
# differential_evolution step 121: f(x)= 748.9679098980329
# differential_evolution step 122: f(x)= 748.9679098980329
# differential_evolution step 123: f(x)= 748.9679098980329
# differential_evolution step 124: f(x)= 748.9679098980329
# differential_evolution step 125: f(x)= 705.9201475956818
# differential_evolution step 126: f(x)= 705.9201475956818
# differential_evolution step 127: f(x)= 705.9201475956818
# differential_evolution step 128: f(x)= 705.9201475956818
# differential_evolution step 129: f(x)= 487.3320083542378
# differential_evolution step 130: f(x)= 487.3320083542378
# differential_evolution step 131: f(x)= 487.3320083542378
# differential_evolution step 132: f(x)= 487.3320083542378
# differential_evolution step 133: f(x)= 487.3320083542378
# differential_evolution step 134: f(x)= 487.3320083542378
# differential_evolution step 135: f(x)= 487.3320083542378
# differential_evolution step 136: f(x)= 487.3320083542378
# differential_evolution step 137: f(x)= 487.3320083542378
# differential_evolution step 138: f(x)= 487.3320083542378
# differential_evolution step 139: f(x)= 487.3320083542378
# differential_evolution step 140: f(x)= 487.3320083542378
# differential_evolution step 141: f(x)= 487.3320083542378
# differential_evolution step 142: f(x)= 487.3320083542378
# differential_evolution step 143: f(x)= 487.3320083542378
# differential_evolution step 144: f(x)= 487.3320083542378
# differential_evolution step 145: f(x)= 487.3320083542378
# differential_evolution step 146: f(x)= 487.3320083542378
# differential_evolution step 147: f(x)= 487.3320083542378
# differential_evolution step 148: f(x)= 487.3320083542378
# differential_evolution step 149: f(x)= 487.3320083542378
# differential_evolution step 150: f(x)= 487.3320083542378
# differential_evolution step 151: f(x)= 487.3320083542378
# differential_evolution step 152: f(x)= 487.3320083542378
# differential_evolution step 153: f(x)= 487.3320083542378
# differential_evolution step 154: f(x)= 487.3320083542378
# differential_evolution step 155: f(x)= 372.6856929090099
# differential_evolution step 156: f(x)= 372.6856929090099
# differential_evolution step 157: f(x)= 372.6856929090099
# differential_evolution step 158: f(x)= 372.6856929090099
# differential_evolution step 159: f(x)= 372.6856929090099
# differential_evolution step 160: f(x)= 372.6856929090099
# differential_evolution step 161: f(x)= 372.6856929090099
# differential_evolution step 162: f(x)= 372.6856929090099
# differential_evolution step 163: f(x)= 372.6856929090099
# differential_evolution step 164: f(x)= 372.6856929090099
# differential_evolution step 165: f(x)= 372.6856929090099
# differential_evolution step 166: f(x)= 372.6856929090099
# differential_evolution step 167: f(x)= 372.6856929090099
# differential_evolution step 168: f(x)= 372.6856929090099
# differential_evolution step 169: f(x)= 372.6856929090099
# differential_evolution step 170: f(x)= 372.6856929090099
# differential_evolution step 171: f(x)= 372.6856929090099
# differential_evolution step 172: f(x)= 372.6856929090099
# differential_evolution step 173: f(x)= 372.6856929090099
# differential_evolution step 174: f(x)= 372.6856929090099
# differential_evolution step 175: f(x)= 372.6856929090099
# differential_evolution step 176: f(x)= 372.6856929090099
# differential_evolution step 177: f(x)= 372.6856929090099
# differential_evolution step 178: f(x)= 372.6856929090099
# differential_evolution step 179: f(x)= 372.6856929090099
# differential_evolution step 180: f(x)= 372.6856929090099
# differential_evolution step 181: f(x)= 372.6856929090099
# differential_evolution step 182: f(x)= 372.6856929090099
# differential_evolution step 183: f(x)= 372.6856929090099
# differential_evolution step 184: f(x)= 372.6856929090099
# differential_evolution step 185: f(x)= 372.6856929090099
# differential_evolution step 186: f(x)= 372.6856929090099
# differential_evolution step 187: f(x)= 372.6856929090099
# differential_evolution step 188: f(x)= 372.6856929090099
# differential_evolution step 189: f(x)= 372.6856929090099
# differential_evolution step 190: f(x)= 372.6856929090099
# differential_evolution step 191: f(x)= 372.6856929090099
# differential_evolution step 192: f(x)= 324.9549778505374
# differential_evolution step 193: f(x)= 324.9549778505374
# differential_evolution step 194: f(x)= 324.9549778505374
# differential_evolution step 195: f(x)= 324.9549778505374
# differential_evolution step 196: f(x)= 324.9549778505374
# differential_evolution step 197: f(x)= 324.9549778505374
# differential_evolution step 198: f(x)= 324.9549778505374
# differential_evolution step 199: f(x)= 324.9549778505374
# differential_evolution step 200: f(x)= 324.9549778505374
# differential_evolution step 201: f(x)= 324.9549778505374
# differential_evolution step 202: f(x)= 324.9549778505374
# differential_evolution step 203: f(x)= 324.9549778505374
# differential_evolution step 204: f(x)= 324.9549778505374
# differential_evolution step 205: f(x)= 324.9549778505374
# differential_evolution step 206: f(x)= 324.9549778505374
# differential_evolution step 207: f(x)= 324.9549778505374
# differential_evolution step 208: f(x)= 324.9549778505374
# differential_evolution step 209: f(x)= 324.9549778505374
# differential_evolution step 210: f(x)= 324.9549778505374
# differential_evolution step 211: f(x)= 324.9549778505374
# differential_evolution step 212: f(x)= 317.49731583391633
# differential_evolution step 213: f(x)= 317.49731583391633
# differential_evolution step 214: f(x)= 317.49731583391633
# differential_evolution step 215: f(x)= 317.49731583391633
# differential_evolution step 216: f(x)= 315.8136499478374
# differential_evolution step 217: f(x)= 315.8136499478374
# differential_evolution step 218: f(x)= 315.8136499478374
# differential_evolution step 219: f(x)= 315.8136499478374
# differential_evolution step 220: f(x)= 315.8136499478374
# differential_evolution step 221: f(x)= 315.8136499478374
# differential_evolution step 222: f(x)= 307.4641948980579
# differential_evolution step 223: f(x)= 307.4641948980579
# differential_evolution step 224: f(x)= 307.4641948980579
# differential_evolution step 225: f(x)= 307.4641948980579
# differential_evolution step 226: f(x)= 307.4641948980579
# differential_evolution step 227: f(x)= 292.23208689175675
# differential_evolution step 228: f(x)= 292.23208689175675
# differential_evolution step 229: f(x)= 292.23208689175675
# differential_evolution step 230: f(x)= 292.23208689175675
# differential_evolution step 231: f(x)= 292.23208689175675
# differential_evolution step 232: f(x)= 292.23208689175675
# differential_evolution step 233: f(x)= 292.23208689175675
# differential_evolution step 234: f(x)= 292.23208689175675
# differential_evolution step 235: f(x)= 274.06201941042593
# differential_evolution step 236: f(x)= 274.06201941042593
# differential_evolution step 237: f(x)= 274.06201941042593
# differential_evolution step 238: f(x)= 274.06201941042593
# differential_evolution step 239: f(x)= 274.06201941042593
# differential_evolution step 240: f(x)= 261.7763208655579
# differential_evolution step 241: f(x)= 261.7763208655579
# differential_evolution step 242: f(x)= 261.7763208655579
# differential_evolution step 243: f(x)= 261.7763208655579
# differential_evolution step 244: f(x)= 261.7763208655579
# differential_evolution step 245: f(x)= 261.7763208655579
# differential_evolution step 246: f(x)= 261.7763208655579
# differential_evolution step 247: f(x)= 261.7763208655579
# differential_evolution step 248: f(x)= 225.55685830026906
# differential_evolution step 249: f(x)= 225.55685830026906
# differential_evolution step 250: f(x)= 225.55685830026906
# differential_evolution step 251: f(x)= 225.55685830026906
# differential_evolution step 252: f(x)= 225.55685830026906
# differential_evolution step 253: f(x)= 225.55685830026906
# differential_evolution step 254: f(x)= 225.55685830026906
# differential_evolution step 255: f(x)= 225.55685830026906
# differential_evolution step 256: f(x)= 225.55685830026906
# differential_evolution step 257: f(x)= 225.55685830026906
# differential_evolution step 258: f(x)= 225.55685830026906
# differential_evolution step 259: f(x)= 225.55685830026906
# differential_evolution step 260: f(x)= 225.55685830026906
# differential_evolution step 261: f(x)= 225.55685830026906
# differential_evolution step 262: f(x)= 225.55685830026906
# differential_evolution step 263: f(x)= 225.55685830026906
# differential_evolution step 264: f(x)= 225.55685830026906
# differential_evolution step 265: f(x)= 225.55685830026906
# differential_evolution step 266: f(x)= 225.55685830026906
# differential_evolution step 267: f(x)= 225.55685830026906
# differential_evolution step 268: f(x)= 225.55685830026906
# differential_evolution step 269: f(x)= 225.55685830026906
# differential_evolution step 270: f(x)= 225.55685830026906
# differential_evolution step 271: f(x)= 219.79379112827118
# differential_evolution step 272: f(x)= 219.79379112827118
# differential_evolution step 273: f(x)= 219.79379112827118
# differential_evolution step 274: f(x)= 219.79379112827118
# differential_evolution step 275: f(x)= 219.79379112827118
# differential_evolution step 276: f(x)= 219.79379112827118
# differential_evolution step 277: f(x)= 215.3132672573326
# differential_evolution step 278: f(x)= 215.3132672573326
# differential_evolution step 279: f(x)= 215.3132672573326
# differential_evolution step 280: f(x)= 215.3132672573326
# differential_evolution step 281: f(x)= 215.3132672573326
# differential_evolution step 282: f(x)= 215.3132672573326
# differential_evolution step 283: f(x)= 215.3132672573326
# differential_evolution step 284: f(x)= 215.3132672573326
# differential_evolution step 285: f(x)= 215.3132672573326
# differential_evolution step 286: f(x)= 215.3132672573326
# differential_evolution step 287: f(x)= 215.3132672573326
# differential_evolution step 288: f(x)= 215.3132672573326
# differential_evolution step 289: f(x)= 215.3132672573326
# differential_evolution step 290: f(x)= 213.21042297414598
# differential_evolution step 291: f(x)= 213.21042297414598
# differential_evolution step 292: f(x)= 213.21042297414598
# differential_evolution step 293: f(x)= 213.21042297414598
# differential_evolution step 294: f(x)= 213.21042297414598
# differential_evolution step 295: f(x)= 213.21042297414598
# differential_evolution step 296: f(x)= 213.21042297414598
# differential_evolution step 297: f(x)= 213.21042297414598
# differential_evolution step 298: f(x)= 213.21042297414598
# differential_evolution step 299: f(x)= 213.21042297414598
# differential_evolution step 300: f(x)= 213.21042297414598
# differential_evolution step 301: f(x)= 213.21042297414598
# differential_evolution step 302: f(x)= 213.21042297414598
# differential_evolution step 303: f(x)= 213.21042297414598
# differential_evolution step 304: f(x)= 210.83059800484915
# differential_evolution step 305: f(x)= 210.83059800484915
# differential_evolution step 306: f(x)= 210.83059800484915
# differential_evolution step 307: f(x)= 210.83059800484915
# differential_evolution step 308: f(x)= 210.83059800484915
# differential_evolution step 309: f(x)= 210.83059800484915
# differential_evolution step 310: f(x)= 210.83059800484915
# differential_evolution step 311: f(x)= 210.83059800484915
# differential_evolution step 312: f(x)= 195.01813617385616
# differential_evolution step 313: f(x)= 195.01813617385616
# differential_evolution step 314: f(x)= 195.01813617385616
# differential_evolution step 315: f(x)= 195.01813617385616
# differential_evolution step 316: f(x)= 195.01813617385616
# differential_evolution step 317: f(x)= 195.01813617385616
# differential_evolution step 318: f(x)= 195.01813617385616
# differential_evolution step 319: f(x)= 195.01813617385616
# differential_evolution step 320: f(x)= 195.01813617385616
# differential_evolution step 321: f(x)= 195.01813617385616
# differential_evolution step 322: f(x)= 195.01813617385616
# differential_evolution step 323: f(x)= 195.01813617385616
# differential_evolution step 324: f(x)= 195.01813617385616
# differential_evolution step 325: f(x)= 195.01813617385616
# differential_evolution step 326: f(x)= 195.01813617385616
# differential_evolution step 327: f(x)= 195.01813617385616
# differential_evolution step 328: f(x)= 195.01813617385616
# differential_evolution step 329: f(x)= 195.01813617385616
# differential_evolution step 330: f(x)= 195.01813617385616
# differential_evolution step 331: f(x)= 195.01813617385616
# differential_evolution step 332: f(x)= 195.01813617385616
# differential_evolution step 333: f(x)= 195.01813617385616
# differential_evolution step 334: f(x)= 194.7653173894478
# differential_evolution step 335: f(x)= 194.7653173894478
# differential_evolution step 336: f(x)= 194.7653173894478
# differential_evolution step 337: f(x)= 194.7653173894478
# differential_evolution step 338: f(x)= 184.75998905658392
# differential_evolution step 339: f(x)= 184.75998905658392
# differential_evolution step 340: f(x)= 184.75998905658392
# differential_evolution step 341: f(x)= 184.75998905658392
# differential_evolution step 342: f(x)= 184.75998905658392
# differential_evolution step 343: f(x)= 184.75998905658392
# differential_evolution step 344: f(x)= 184.75998905658392
# differential_evolution step 345: f(x)= 184.75998905658392
# differential_evolution step 346: f(x)= 167.66671624785158
# differential_evolution step 347: f(x)= 167.66671624785158
# differential_evolution step 348: f(x)= 167.66671624785158
# differential_evolution step 349: f(x)= 167.66671624785158
# differential_evolution step 350: f(x)= 167.66671624785158
# differential_evolution step 351: f(x)= 167.66671624785158
# differential_evolution step 352: f(x)= 167.66671624785158
# differential_evolution step 353: f(x)= 167.66671624785158
# differential_evolution step 354: f(x)= 167.66671624785158
# differential_evolution step 355: f(x)= 167.66671624785158
# differential_evolution step 356: f(x)= 167.66671624785158
# differential_evolution step 357: f(x)= 167.66671624785158
# differential_evolution step 358: f(x)= 167.66671624785158
# differential_evolution step 359: f(x)= 167.66671624785158
# differential_evolution step 360: f(x)= 159.8626905648075
# differential_evolution step 361: f(x)= 159.8626905648075
# differential_evolution step 362: f(x)= 159.8626905648075
# differential_evolution step 363: f(x)= 159.8626905648075
# differential_evolution step 364: f(x)= 159.8626905648075
# differential_evolution step 365: f(x)= 159.8626905648075
# differential_evolution step 366: f(x)= 159.8626905648075
# differential_evolution step 367: f(x)= 159.8626905648075
# differential_evolution step 368: f(x)= 159.8626905648075
# differential_evolution step 369: f(x)= 159.8626905648075
# differential_evolution step 370: f(x)= 159.8626905648075
# differential_evolution step 371: f(x)= 159.8626905648075
# differential_evolution step 372: f(x)= 159.8626905648075
# differential_evolution step 373: f(x)= 159.8626905648075
# differential_evolution step 374: f(x)= 159.8626905648075
# differential_evolution step 375: f(x)= 159.8626905648075
# differential_evolution step 376: f(x)= 159.8626905648075
# differential_evolution step 377: f(x)= 159.79558836793316
# differential_evolution step 378: f(x)= 159.79558836793316
# differential_evolution step 379: f(x)= 159.79558836793316
# differential_evolution step 380: f(x)= 159.79558836793316
# differential_evolution step 381: f(x)= 159.79558836793316
# differential_evolution step 382: f(x)= 159.79558836793316
# differential_evolution step 383: f(x)= 159.79558836793316
# differential_evolution step 384: f(x)= 159.79558836793316
# differential_evolution step 385: f(x)= 159.79558836793316
# differential_evolution step 386: f(x)= 153.51576713572834
# differential_evolution step 387: f(x)= 153.51576713572834
# differential_evolution step 388: f(x)= 153.51576713572834
# differential_evolution step 389: f(x)= 153.51576713572834
# differential_evolution step 390: f(x)= 153.51576713572834
# differential_evolution step 391: f(x)= 153.51576713572834
# differential_evolution step 392: f(x)= 153.51576713572834
# differential_evolution step 393: f(x)= 153.51576713572834
# differential_evolution step 394: f(x)= 153.51576713572834
# differential_evolution step 395: f(x)= 153.51576713572834
# differential_evolution step 396: f(x)= 153.51576713572834
# differential_evolution step 397: f(x)= 153.51576713572834
# differential_evolution step 398: f(x)= 153.51576713572834
# differential_evolution step 399: f(x)= 150.12209048525065
# differential_evolution step 400: f(x)= 150.12209048525065
# differential_evolution step 401: f(x)= 150.12209048525065
# differential_evolution step 402: f(x)= 150.12209048525065
# differential_evolution step 403: f(x)= 150.12209048525065
# differential_evolution step 404: f(x)= 150.12209048525065
# differential_evolution step 405: f(x)= 150.12209048525065
# differential_evolution step 406: f(x)= 150.12209048525065
# differential_evolution step 407: f(x)= 150.12209048525065
# differential_evolution step 408: f(x)= 150.12209048525065
# differential_evolution step 409: f(x)= 150.12209048525065
# differential_evolution step 410: f(x)= 150.12209048525065
# differential_evolution step 411: f(x)= 150.12209048525065
# differential_evolution step 412: f(x)= 150.12209048525065
# differential_evolution step 413: f(x)= 150.12209048525065
# differential_evolution step 414: f(x)= 150.12209048525065
# differential_evolution step 415: f(x)= 150.12209048525065
# differential_evolution step 416: f(x)= 150.12209048525065
# differential_evolution step 417: f(x)= 150.12209048525065
# differential_evolution step 418: f(x)= 150.12209048525065
# differential_evolution step 419: f(x)= 143.8523302068363
# differential_evolution step 420: f(x)= 143.8523302068363
# differential_evolution step 421: f(x)= 143.8523302068363
# differential_evolution step 422: f(x)= 143.8523302068363
# differential_evolution step 423: f(x)= 143.8523302068363
# differential_evolution step 424: f(x)= 143.8523302068363
# differential_evolution step 425: f(x)= 143.8523302068363
# differential_evolution step 426: f(x)= 143.8523302068363
# differential_evolution step 427: f(x)= 143.8523302068363
# differential_evolution step 428: f(x)= 143.8523302068363
# differential_evolution step 429: f(x)= 143.8523302068363
# differential_evolution step 430: f(x)= 143.8523302068363
# differential_evolution step 431: f(x)= 143.8523302068363
# differential_evolution step 432: f(x)= 143.8523302068363
# differential_evolution step 433: f(x)= 143.8523302068363
# differential_evolution step 434: f(x)= 143.8523302068363
# differential_evolution step 435: f(x)= 143.8523302068363
# differential_evolution step 436: f(x)= 143.8523302068363
# differential_evolution step 437: f(x)= 143.8523302068363
# differential_evolution step 438: f(x)= 143.8523302068363
# differential_evolution step 439: f(x)= 143.8523302068363
# differential_evolution step 440: f(x)= 143.8523302068363
# differential_evolution step 441: f(x)= 143.8523302068363
# differential_evolution step 442: f(x)= 143.8523302068363
# differential_evolution step 443: f(x)= 143.8523302068363
# differential_evolution step 444: f(x)= 143.8523302068363
# differential_evolution step 445: f(x)= 143.8523302068363
# differential_evolution step 446: f(x)= 143.8523302068363
# differential_evolution step 447: f(x)= 143.8523302068363
# differential_evolution step 448: f(x)= 143.8523302068363
# differential_evolution step 449: f(x)= 143.8523302068363
# differential_evolution step 450: f(x)= 143.8523302068363
# differential_evolution step 451: f(x)= 143.8523302068363
# differential_evolution step 452: f(x)= 143.8523302068363
# differential_evolution step 453: f(x)= 143.8523302068363
# differential_evolution step 454: f(x)= 143.8523302068363
# differential_evolution step 455: f(x)= 143.8523302068363
# differential_evolution step 456: f(x)= 143.8523302068363
# differential_evolution step 457: f(x)= 143.8523302068363
# differential_evolution step 458: f(x)= 143.8523302068363
# differential_evolution step 459: f(x)= 143.8523302068363
# differential_evolution step 460: f(x)= 143.8523302068363
# differential_evolution step 461: f(x)= 143.8523302068363
# differential_evolution step 462: f(x)= 143.8523302068363
# differential_evolution step 463: f(x)= 143.32966654599085
# differential_evolution step 464: f(x)= 143.32966654599085
# differential_evolution step 465: f(x)= 143.32966654599085
# differential_evolution step 466: f(x)= 143.32966654599085
# differential_evolution step 467: f(x)= 143.32966654599085
# differential_evolution step 468: f(x)= 143.32966654599085
# differential_evolution step 469: f(x)= 143.32966654599085
# differential_evolution step 470: f(x)= 143.32966654599085
# differential_evolution step 471: f(x)= 138.4850101264375
# differential_evolution step 472: f(x)= 138.4850101264375
# differential_evolution step 473: f(x)= 138.4850101264375
# differential_evolution step 474: f(x)= 138.4850101264375
# differential_evolution step 475: f(x)= 138.4850101264375
# differential_evolution step 476: f(x)= 138.4850101264375
# differential_evolution step 477: f(x)= 138.4850101264375
# differential_evolution step 478: f(x)= 138.4850101264375
# differential_evolution step 479: f(x)= 138.4850101264375
# differential_evolution step 480: f(x)= 138.4850101264375
# differential_evolution step 481: f(x)= 136.4481187988504
# differential_evolution step 482: f(x)= 136.4481187988504
# differential_evolution step 483: f(x)= 136.4481187988504
# differential_evolution step 484: f(x)= 136.4481187988504
# differential_evolution step 485: f(x)= 136.4481187988504
# differential_evolution step 486: f(x)= 136.4481187988504
# differential_evolution step 487: f(x)= 136.4481187988504
# differential_evolution step 488: f(x)= 136.4481187988504
# differential_evolution step 489: f(x)= 136.4481187988504
# differential_evolution step 490: f(x)= 136.4481187988504
# differential_evolution step 491: f(x)= 136.4481187988504
# differential_evolution step 492: f(x)= 136.4481187988504
# differential_evolution step 493: f(x)= 136.4481187988504
# differential_evolution step 494: f(x)= 136.4481187988504
# differential_evolution step 495: f(x)= 135.72365228072977
# differential_evolution step 496: f(x)= 135.72365228072977
# differential_evolution step 497: f(x)= 135.72365228072977
# differential_evolution step 498: f(x)= 135.72365228072977
# differential_evolution step 499: f(x)= 135.72365228072977
# differential_evolution step 500: f(x)= 135.72365228072977
# differential_evolution step 501: f(x)= 135.72365228072977
# differential_evolution step 502: f(x)= 135.72365228072977
# differential_evolution step 503: f(x)= 135.72365228072977
# differential_evolution step 504: f(x)= 135.72365228072977
# differential_evolution step 505: f(x)= 135.72365228072977
# differential_evolution step 506: f(x)= 135.72365228072977
# differential_evolution step 507: f(x)= 135.72365228072977
# differential_evolution step 508: f(x)= 135.72365228072977
# differential_evolution step 509: f(x)= 135.72365228072977
# differential_evolution step 510: f(x)= 135.72365228072977
# differential_evolution step 511: f(x)= 135.72365228072977
# differential_evolution step 512: f(x)= 135.72365228072977
# differential_evolution step 513: f(x)= 135.72365228072977
# differential_evolution step 514: f(x)= 135.72365228072977
# differential_evolution step 515: f(x)= 135.72365228072977
# differential_evolution step 516: f(x)= 135.72365228072977
# differential_evolution step 517: f(x)= 135.72365228072977
# differential_evolution step 518: f(x)= 135.72365228072977
# differential_evolution step 519: f(x)= 133.81974552636083
# differential_evolution step 520: f(x)= 133.81974552636083
# differential_evolution step 521: f(x)= 133.81974552636083
# differential_evolution step 522: f(x)= 133.81974552636083
# differential_evolution step 523: f(x)= 133.81974552636083
# differential_evolution step 524: f(x)= 133.81974552636083
# differential_evolution step 525: f(x)= 131.69510612631316
# differential_evolution step 526: f(x)= 131.69510612631316
# differential_evolution step 527: f(x)= 131.69510612631316
# differential_evolution step 528: f(x)= 131.69510612631316
# differential_evolution step 529: f(x)= 131.69510612631316
# differential_evolution step 530: f(x)= 131.69510612631316
# differential_evolution step 531: f(x)= 131.69510612631316
# differential_evolution step 532: f(x)= 131.69510612631316
# differential_evolution step 533: f(x)= 131.69510612631316
# differential_evolution step 534: f(x)= 131.69510612631316
# differential_evolution step 535: f(x)= 131.69510612631316
# differential_evolution step 536: f(x)= 131.69510612631316
# differential_evolution step 537: f(x)= 129.90116642625657
# differential_evolution step 538: f(x)= 129.90116642625657
# differential_evolution step 539: f(x)= 129.90116642625657
# differential_evolution step 540: f(x)= 129.77929510732906
# differential_evolution step 541: f(x)= 129.77929510732906
# differential_evolution step 542: f(x)= 129.77929510732906
# differential_evolution step 543: f(x)= 129.77929510732906
# differential_evolution step 544: f(x)= 129.77929510732906
# differential_evolution step 545: f(x)= 129.77929510732906
# differential_evolution step 546: f(x)= 129.77929510732906
# differential_evolution step 547: f(x)= 129.77929510732906
# differential_evolution step 548: f(x)= 129.77929510732906
# differential_evolution step 549: f(x)= 129.77929510732906
# differential_evolution step 550: f(x)= 129.77929510732906
# differential_evolution step 551: f(x)= 129.77929510732906
# differential_evolution step 552: f(x)= 129.77929510732906
# differential_evolution step 553: f(x)= 129.77929510732906
# differential_evolution step 554: f(x)= 129.77929510732906
# differential_evolution step 555: f(x)= 129.77929510732906
# differential_evolution step 556: f(x)= 129.77929510732906
# differential_evolution step 557: f(x)= 129.46097634046328
# differential_evolution step 558: f(x)= 129.46097634046328
# differential_evolution step 559: f(x)= 129.46097634046328
# differential_evolution step 560: f(x)= 129.46097634046328
# differential_evolution step 561: f(x)= 129.46097634046328
# differential_evolution step 562: f(x)= 129.46097634046328
# differential_evolution step 563: f(x)= 129.46097634046328
# differential_evolution step 564: f(x)= 129.46097634046328
# differential_evolution step 565: f(x)= 129.46097634046328
# differential_evolution step 566: f(x)= 129.46097634046328
# differential_evolution step 567: f(x)= 129.46097634046328
# differential_evolution step 568: f(x)= 129.46097634046328
# differential_evolution step 569: f(x)= 129.46097634046328
# differential_evolution step 570: f(x)= 129.46097634046328
# differential_evolution step 571: f(x)= 129.46097634046328
# differential_evolution step 572: f(x)= 129.46097634046328
# differential_evolution step 573: f(x)= 129.46097634046328
# differential_evolution step 574: f(x)= 129.46097634046328
# differential_evolution step 575: f(x)= 129.31952511092646
# differential_evolution step 576: f(x)= 129.31952511092646
# differential_evolution step 577: f(x)= 129.31952511092646
# differential_evolution step 578: f(x)= 124.73841249095125
# differential_evolution step 579: f(x)= 124.73841249095125
# differential_evolution step 580: f(x)= 124.73841249095125
# differential_evolution step 581: f(x)= 124.73841249095125
# differential_evolution step 582: f(x)= 124.73841249095125
# differential_evolution step 583: f(x)= 124.73841249095125
# differential_evolution step 584: f(x)= 124.73841249095125
# differential_evolution step 585: f(x)= 124.73841249095125
# differential_evolution step 586: f(x)= 124.73841249095125
# differential_evolution step 587: f(x)= 124.73841249095125
# differential_evolution step 588: f(x)= 124.73841249095125
# differential_evolution step 589: f(x)= 124.73841249095125
# differential_evolution step 590: f(x)= 124.73841249095125
# differential_evolution step 591: f(x)= 124.73841249095125
# differential_evolution step 592: f(x)= 124.73841249095125
# differential_evolution step 593: f(x)= 124.73841249095125
# differential_evolution step 594: f(x)= 124.73841249095125
# differential_evolution step 595: f(x)= 124.73841249095125
# differential_evolution step 596: f(x)= 124.73841249095125
# differential_evolution step 597: f(x)= 124.73841249095125
# differential_evolution step 598: f(x)= 124.73841249095125
# differential_evolution step 599: f(x)= 124.73841249095125
# differential_evolution step 600: f(x)= 124.73841249095125
# differential_evolution step 601: f(x)= 124.73841249095125
# differential_evolution step 602: f(x)= 124.73841249095125
# differential_evolution step 603: f(x)= 124.73841249095125
# differential_evolution step 604: f(x)= 124.73841249095125
# differential_evolution step 605: f(x)= 124.73841249095125
# differential_evolution step 606: f(x)= 124.73841249095125
# differential_evolution step 607: f(x)= 124.73841249095125
# differential_evolution step 608: f(x)= 124.73841249095125
# differential_evolution step 609: f(x)= 124.73841249095125
# differential_evolution step 610: f(x)= 124.73841249095125
# differential_evolution step 611: f(x)= 124.73841249095125
# differential_evolution step 612: f(x)= 124.73841249095125
# differential_evolution step 613: f(x)= 124.73841249095125
# differential_evolution step 614: f(x)= 124.73841249095125
# differential_evolution step 615: f(x)= 124.73841249095125
# differential_evolution step 616: f(x)= 124.73841249095125
# differential_evolution step 617: f(x)= 124.73841249095125
# differential_evolution step 618: f(x)= 124.73841249095125
# differential_evolution step 619: f(x)= 124.73841249095125
# differential_evolution step 620: f(x)= 124.73841249095125
# differential_evolution step 621: f(x)= 124.73841249095125
# differential_evolution step 622: f(x)= 124.73841249095125
# differential_evolution step 623: f(x)= 124.73841249095125
# differential_evolution step 624: f(x)= 124.73841249095125
# differential_evolution step 625: f(x)= 124.73841249095125
# differential_evolution step 626: f(x)= 123.42112094896981
# differential_evolution step 627: f(x)= 123.42112094896981
# differential_evolution step 628: f(x)= 123.42112094896981
# differential_evolution step 629: f(x)= 123.42112094896981
# differential_evolution step 630: f(x)= 123.42112094896981
# differential_evolution step 631: f(x)= 123.42112094896981
# differential_evolution step 632: f(x)= 123.42112094896981
# differential_evolution step 633: f(x)= 123.42112094896981
# differential_evolution step 634: f(x)= 123.42112094896981
# differential_evolution step 635: f(x)= 123.42112094896981
# differential_evolution step 636: f(x)= 123.42112094896981
# differential_evolution step 637: f(x)= 123.42112094896981
# differential_evolution step 638: f(x)= 123.42112094896981
# differential_evolution step 639: f(x)= 123.42112094896981
# differential_evolution step 640: f(x)= 123.42112094896981
# differential_evolution step 641: f(x)= 123.42112094896981
# differential_evolution step 642: f(x)= 123.42112094896981
# differential_evolution step 643: f(x)= 123.42112094896981
# differential_evolution step 644: f(x)= 123.42112094896981
# differential_evolution step 645: f(x)= 123.42112094896981
# differential_evolution step 646: f(x)= 123.42112094896981
# differential_evolution step 647: f(x)= 123.42112094896981
# differential_evolution step 648: f(x)= 123.42112094896981
# differential_evolution step 649: f(x)= 123.42112094896981
# differential_evolution step 650: f(x)= 123.42112094896981
# differential_evolution step 651: f(x)= 120.155062858289
# differential_evolution step 652: f(x)= 120.155062858289
# differential_evolution step 653: f(x)= 120.155062858289
# differential_evolution step 654: f(x)= 120.155062858289
# differential_evolution step 655: f(x)= 120.155062858289
# differential_evolution step 656: f(x)= 120.155062858289
# differential_evolution step 657: f(x)= 120.155062858289
# differential_evolution step 658: f(x)= 120.155062858289
# differential_evolution step 659: f(x)= 120.155062858289
# differential_evolution step 660: f(x)= 120.155062858289
# differential_evolution step 661: f(x)= 120.155062858289
# differential_evolution step 662: f(x)= 120.155062858289
# differential_evolution step 663: f(x)= 120.155062858289
# differential_evolution step 664: f(x)= 120.155062858289
# differential_evolution step 665: f(x)= 120.155062858289
# differential_evolution step 666: f(x)= 120.155062858289
# differential_evolution step 667: f(x)= 120.155062858289
# differential_evolution step 668: f(x)= 120.155062858289
# differential_evolution step 669: f(x)= 120.155062858289
# differential_evolution step 670: f(x)= 120.155062858289
# differential_evolution step 671: f(x)= 120.155062858289
# differential_evolution step 672: f(x)= 120.155062858289
# differential_evolution step 673: f(x)= 120.155062858289
# differential_evolution step 674: f(x)= 120.155062858289
# differential_evolution step 675: f(x)= 120.155062858289
# differential_evolution step 676: f(x)= 120.155062858289
# differential_evolution step 677: f(x)= 120.155062858289
# differential_evolution step 678: f(x)= 120.155062858289
# differential_evolution step 679: f(x)= 120.155062858289
# differential_evolution step 680: f(x)= 120.155062858289
# differential_evolution step 681: f(x)= 120.155062858289
# differential_evolution step 682: f(x)= 120.155062858289
# differential_evolution step 683: f(x)= 120.155062858289
# differential_evolution step 684: f(x)= 120.155062858289
# differential_evolution step 685: f(x)= 120.155062858289
# differential_evolution step 686: f(x)= 120.155062858289
# differential_evolution step 687: f(x)= 120.155062858289
# differential_evolution step 688: f(x)= 120.155062858289
# differential_evolution step 689: f(x)= 120.155062858289
# differential_evolution step 690: f(x)= 120.155062858289
# differential_evolution step 691: f(x)= 120.155062858289
# differential_evolution step 692: f(x)= 120.155062858289
# differential_evolution step 693: f(x)= 120.155062858289
# differential_evolution step 694: f(x)= 119.32636750691312
# differential_evolution step 695: f(x)= 119.32636750691312
# differential_evolution step 696: f(x)= 119.32636750691312
# differential_evolution step 697: f(x)= 119.32636750691312
# differential_evolution step 698: f(x)= 119.32636750691312
# differential_evolution step 699: f(x)= 119.32636750691312
# differential_evolution step 700: f(x)= 119.32636750691312
# differential_evolution step 701: f(x)= 119.32636750691312
# differential_evolution step 702: f(x)= 119.32636750691312
# differential_evolution step 703: f(x)= 119.32636750691312
# differential_evolution step 704: f(x)= 119.32636750691312
# differential_evolution step 705: f(x)= 119.32636750691312
# differential_evolution step 706: f(x)= 119.32636750691312
# differential_evolution step 707: f(x)= 119.17081225209117
# differential_evolution step 708: f(x)= 119.17081225209117
# differential_evolution step 709: f(x)= 119.17081225209117
# differential_evolution step 710: f(x)= 119.17081225209117
# differential_evolution step 711: f(x)= 119.17081225209117
# differential_evolution step 712: f(x)= 119.17081225209117
# differential_evolution step 713: f(x)= 119.17081225209117
# differential_evolution step 714: f(x)= 119.17081225209117
# differential_evolution step 715: f(x)= 119.17081225209117
# differential_evolution step 716: f(x)= 119.17081225209117
# differential_evolution step 717: f(x)= 119.17081225209117
# differential_evolution step 718: f(x)= 119.17081225209117
# differential_evolution step 719: f(x)= 118.8224610114485
# differential_evolution step 720: f(x)= 118.8224610114485
# differential_evolution step 721: f(x)= 118.8224610114485
# differential_evolution step 722: f(x)= 118.8224610114485
# differential_evolution step 723: f(x)= 118.8224610114485
# differential_evolution step 724: f(x)= 118.8224610114485
# differential_evolution step 725: f(x)= 118.8224610114485
# differential_evolution step 726: f(x)= 118.8224610114485
# differential_evolution step 727: f(x)= 118.8224610114485
# differential_evolution step 728: f(x)= 118.8224610114485
# differential_evolution step 729: f(x)= 118.8224610114485
# differential_evolution step 730: f(x)= 118.8224610114485
# differential_evolution step 731: f(x)= 118.8224610114485
# differential_evolution step 732: f(x)= 118.8224610114485
# differential_evolution step 733: f(x)= 118.8224610114485
# differential_evolution step 734: f(x)= 118.29121349092911
# differential_evolution step 735: f(x)= 118.29121349092911
# differential_evolution step 736: f(x)= 118.29121349092911
# differential_evolution step 737: f(x)= 118.29121349092911
# differential_evolution step 738: f(x)= 118.29121349092911
# differential_evolution step 739: f(x)= 118.29121349092911
# differential_evolution step 740: f(x)= 118.29121349092911
# differential_evolution step 741: f(x)= 118.29121349092911
# differential_evolution step 742: f(x)= 118.29121349092911
# differential_evolution step 743: f(x)= 118.29121349092911
# differential_evolution step 744: f(x)= 118.29121349092911
# differential_evolution step 745: f(x)= 118.29121349092911
# differential_evolution step 746: f(x)= 118.29121349092911
# differential_evolution step 747: f(x)= 118.29121349092911
# differential_evolution step 748: f(x)= 118.29121349092911
# differential_evolution step 749: f(x)= 118.29121349092911
# differential_evolution step 750: f(x)= 118.29121349092911
# differential_evolution step 751: f(x)= 118.29121349092911
# differential_evolution step 752: f(x)= 118.29121349092911
# differential_evolution step 753: f(x)= 118.29121349092911
# differential_evolution step 754: f(x)= 118.29121349092911
# differential_evolution step 755: f(x)= 118.29121349092911
# differential_evolution step 756: f(x)= 118.29121349092911
# differential_evolution step 757: f(x)= 118.29121349092911
# differential_evolution step 758: f(x)= 118.29121349092911
# differential_evolution step 759: f(x)= 118.29121349092911
# differential_evolution step 760: f(x)= 118.29121349092911
# differential_evolution step 761: f(x)= 118.29121349092911
# differential_evolution step 762: f(x)= 118.29121349092911
# differential_evolution step 763: f(x)= 118.29121349092911
# differential_evolution step 764: f(x)= 118.28611064798613
# differential_evolution step 765: f(x)= 118.28611064798613
# differential_evolution step 766: f(x)= 118.28611064798613
# differential_evolution step 767: f(x)= 118.28611064798613
# differential_evolution step 768: f(x)= 118.28611064798613
# differential_evolution step 769: f(x)= 118.28611064798613
# differential_evolution step 770: f(x)= 118.28611064798613
# differential_evolution step 771: f(x)= 116.79245139683213
# differential_evolution step 772: f(x)= 116.79245139683213
# differential_evolution step 773: f(x)= 116.79245139683213
# differential_evolution step 774: f(x)= 116.79245139683213
# differential_evolution step 775: f(x)= 116.79245139683213
# differential_evolution step 776: f(x)= 116.79245139683213
# differential_evolution step 777: f(x)= 116.79245139683213
# differential_evolution step 778: f(x)= 116.79245139683213
# differential_evolution step 779: f(x)= 116.79245139683213
# differential_evolution step 780: f(x)= 116.79245139683213
# differential_evolution step 781: f(x)= 116.79245139683213
# differential_evolution step 782: f(x)= 116.79245139683213
# differential_evolution step 783: f(x)= 116.79245139683213
# differential_evolution step 784: f(x)= 116.79245139683213
# differential_evolution step 785: f(x)= 116.79245139683213
# differential_evolution step 786: f(x)= 116.79245139683213
# differential_evolution step 787: f(x)= 116.79245139683213
# differential_evolution step 788: f(x)= 116.79245139683213
# differential_evolution step 789: f(x)= 116.79245139683213
# differential_evolution step 790: f(x)= 116.79245139683213
# differential_evolution step 791: f(x)= 116.79245139683213
# differential_evolution step 792: f(x)= 116.79245139683213
# differential_evolution step 793: f(x)= 116.79245139683213
# differential_evolution step 794: f(x)= 116.79245139683213
# differential_evolution step 795: f(x)= 116.79245139683213
# differential_evolution step 796: f(x)= 116.79245139683213
# differential_evolution step 797: f(x)= 116.79245139683213
# differential_evolution step 798: f(x)= 116.79245139683213
# differential_evolution step 799: f(x)= 116.79245139683213
# differential_evolution step 800: f(x)= 116.79245139683213
# differential_evolution step 801: f(x)= 116.79245139683213
# differential_evolution step 802: f(x)= 116.79245139683213
# differential_evolution step 803: f(x)= 116.79245139683213
# differential_evolution step 804: f(x)= 116.79245139683213
# differential_evolution step 805: f(x)= 116.79245139683213
# differential_evolution step 806: f(x)= 116.79245139683213
# differential_evolution step 807: f(x)= 113.70307638674794
# differential_evolution step 808: f(x)= 113.70307638674794
# differential_evolution step 809: f(x)= 113.70307638674794
# differential_evolution step 810: f(x)= 113.70307638674794
# differential_evolution step 811: f(x)= 113.70307638674794
# differential_evolution step 812: f(x)= 113.70307638674794
# differential_evolution step 813: f(x)= 113.70307638674794
# differential_evolution step 814: f(x)= 113.70307638674794
# differential_evolution step 815: f(x)= 113.70307638674794
# differential_evolution step 816: f(x)= 113.70307638674794
# differential_evolution step 817: f(x)= 113.70307638674794
# differential_evolution step 818: f(x)= 113.70307638674794
# differential_evolution step 819: f(x)= 113.70307638674794
# differential_evolution step 820: f(x)= 113.70307638674794
# differential_evolution step 821: f(x)= 113.70307638674794
# differential_evolution step 822: f(x)= 113.70307638674794
# differential_evolution step 823: f(x)= 113.70307638674794
# differential_evolution step 824: f(x)= 113.70307638674794
# differential_evolution step 825: f(x)= 113.70307638674794
# differential_evolution step 826: f(x)= 113.70307638674794
# differential_evolution step 827: f(x)= 113.70307638674794
# differential_evolution step 828: f(x)= 113.70307638674794
# differential_evolution step 829: f(x)= 113.70307638674794
# differential_evolution step 830: f(x)= 113.70307638674794
# differential_evolution step 831: f(x)= 113.70307638674794
# differential_evolution step 832: f(x)= 113.70307638674794
# differential_evolution step 833: f(x)= 113.70307638674794
# differential_evolution step 834: f(x)= 113.70307638674794
# differential_evolution step 835: f(x)= 113.70307638674794
# differential_evolution step 836: f(x)= 113.70307638674794
# differential_evolution step 837: f(x)= 113.70307638674794
# differential_evolution step 838: f(x)= 113.70307638674794
# differential_evolution step 839: f(x)= 113.70307638674794
# differential_evolution step 840: f(x)= 113.70307638674794
# differential_evolution step 841: f(x)= 113.70307638674794
# differential_evolution step 842: f(x)= 113.70307638674794
# differential_evolution step 843: f(x)= 113.70307638674794
# differential_evolution step 844: f(x)= 113.70307638674794
# differential_evolution step 845: f(x)= 113.70307638674794
# differential_evolution step 846: f(x)= 113.70307638674794
# differential_evolution step 847: f(x)= 113.70307638674794
# differential_evolution step 848: f(x)= 113.70307638674794
# differential_evolution step 849: f(x)= 113.70307638674794
# differential_evolution step 850: f(x)= 113.70307638674794
# differential_evolution step 851: f(x)= 113.70307638674794
# differential_evolution step 852: f(x)= 113.70307638674794
# differential_evolution step 853: f(x)= 113.70307638674794
# differential_evolution step 854: f(x)= 113.70307638674794
# differential_evolution step 855: f(x)= 113.70307638674794
# differential_evolution step 856: f(x)= 113.70307638674794
# differential_evolution step 857: f(x)= 113.70307638674794
# differential_evolution step 858: f(x)= 113.70307638674794
# differential_evolution step 859: f(x)= 113.70307638674794
# differential_evolution step 860: f(x)= 113.70307638674794
# differential_evolution step 861: f(x)= 112.49753684419802
# differential_evolution step 862: f(x)= 112.49753684419802
# differential_evolution step 863: f(x)= 112.49753684419802
# differential_evolution step 864: f(x)= 112.49753684419802
# differential_evolution step 865: f(x)= 112.49753684419802
# differential_evolution step 866: f(x)= 112.49753684419802
# differential_evolution step 867: f(x)= 112.49753684419802
# differential_evolution step 868: f(x)= 112.49753684419802
# differential_evolution step 869: f(x)= 112.49753684419802
# differential_evolution step 870: f(x)= 112.49753684419802
# differential_evolution step 871: f(x)= 112.49753684419802
# differential_evolution step 872: f(x)= 112.49753684419802
# differential_evolution step 873: f(x)= 112.49753684419802
# differential_evolution step 874: f(x)= 112.49753684419802
# differential_evolution step 875: f(x)= 112.49753684419802
# differential_evolution step 876: f(x)= 112.49753684419802
# differential_evolution step 877: f(x)= 112.49753684419802
# differential_evolution step 878: f(x)= 112.49753684419802
# differential_evolution step 879: f(x)= 112.49753684419802
# differential_evolution step 880: f(x)= 112.49753684419802
# differential_evolution step 881: f(x)= 112.49753684419802
# differential_evolution step 882: f(x)= 112.49753684419802
# differential_evolution step 883: f(x)= 112.49753684419802
# differential_evolution step 884: f(x)= 112.49753684419802
# differential_evolution step 885: f(x)= 112.49753684419802
# differential_evolution step 886: f(x)= 112.49753684419802
# differential_evolution step 887: f(x)= 112.49753684419802
# differential_evolution step 888: f(x)= 112.49753684419802
# differential_evolution step 889: f(x)= 112.49753684419802
# differential_evolution step 890: f(x)= 112.49753684419802
# differential_evolution step 891: f(x)= 112.49753684419802
# differential_evolution step 892: f(x)= 112.49753684419802
# differential_evolution step 893: f(x)= 112.49753684419802
# differential_evolution step 894: f(x)= 112.49753684419802
# differential_evolution step 895: f(x)= 112.3170389189189
# differential_evolution step 896: f(x)= 112.3170389189189
# differential_evolution step 897: f(x)= 112.3170389189189
# differential_evolution step 898: f(x)= 112.3170389189189
# differential_evolution step 899: f(x)= 112.3170389189189
# differential_evolution step 900: f(x)= 112.3170389189189
# differential_evolution step 901: f(x)= 112.3170389189189
# differential_evolution step 902: f(x)= 112.3170389189189
# differential_evolution step 903: f(x)= 112.3170389189189
# differential_evolution step 904: f(x)= 112.3170389189189
# differential_evolution step 905: f(x)= 112.3170389189189
# differential_evolution step 906: f(x)= 112.3170389189189
# differential_evolution step 907: f(x)= 112.3170389189189
# differential_evolution step 908: f(x)= 112.3170389189189
# differential_evolution step 909: f(x)= 112.3170389189189
# differential_evolution step 910: f(x)= 112.3170389189189
# differential_evolution step 911: f(x)= 112.3170389189189
# differential_evolution step 912: f(x)= 112.3170389189189
# differential_evolution step 913: f(x)= 112.3170389189189
# differential_evolution step 914: f(x)= 112.3170389189189
# differential_evolution step 915: f(x)= 112.3170389189189
# differential_evolution step 916: f(x)= 110.19791428742613
# differential_evolution step 917: f(x)= 110.19791428742613
# differential_evolution step 918: f(x)= 110.19791428742613
# differential_evolution step 919: f(x)= 110.19791428742613
# differential_evolution step 920: f(x)= 110.19791428742613
# differential_evolution step 921: f(x)= 110.19791428742613
# differential_evolution step 922: f(x)= 110.19791428742613
# differential_evolution step 923: f(x)= 110.19791428742613
# differential_evolution step 924: f(x)= 110.19791428742613
# differential_evolution step 925: f(x)= 110.19791428742613
# differential_evolution step 926: f(x)= 110.19791428742613
# differential_evolution step 927: f(x)= 110.19791428742613
# differential_evolution step 928: f(x)= 110.19791428742613
# differential_evolution step 929: f(x)= 110.19791428742613
# differential_evolution step 930: f(x)= 110.19791428742613
# differential_evolution step 931: f(x)= 110.19791428742613
# differential_evolution step 932: f(x)= 110.19791428742613
# differential_evolution step 933: f(x)= 110.19791428742613
# differential_evolution step 934: f(x)= 110.19791428742613
# differential_evolution step 935: f(x)= 110.19791428742613
# differential_evolution step 936: f(x)= 110.19791428742613
# differential_evolution step 937: f(x)= 110.19791428742613
# differential_evolution step 938: f(x)= 110.19791428742613
# differential_evolution step 939: f(x)= 110.19791428742613
# differential_evolution step 940: f(x)= 110.19791428742613
# differential_evolution step 941: f(x)= 110.19791428742613
# differential_evolution step 942: f(x)= 110.19791428742613
# differential_evolution step 943: f(x)= 110.19791428742613
# differential_evolution step 944: f(x)= 110.19791428742613
# differential_evolution step 945: f(x)= 110.19791428742613
# differential_evolution step 946: f(x)= 110.19791428742613
# differential_evolution step 947: f(x)= 110.19791428742613
# differential_evolution step 948: f(x)= 110.19791428742613
# differential_evolution step 949: f(x)= 110.19791428742613
# differential_evolution step 950: f(x)= 110.19791428742613
# differential_evolution step 951: f(x)= 110.19791428742613
# differential_evolution step 952: f(x)= 110.19791428742613
# differential_evolution step 953: f(x)= 110.19791428742613
# differential_evolution step 954: f(x)= 110.19791428742613
# differential_evolution step 955: f(x)= 110.19791428742613
# differential_evolution step 956: f(x)= 110.19791428742613
# differential_evolution step 957: f(x)= 110.19791428742613
# differential_evolution step 958: f(x)= 110.19791428742613
# differential_evolution step 959: f(x)= 110.19791428742613
# differential_evolution step 960: f(x)= 110.19791428742613
# differential_evolution step 961: f(x)= 110.19791428742613
# differential_evolution step 962: f(x)= 110.19791428742613
# differential_evolution step 963: f(x)= 110.19791428742613
# differential_evolution step 964: f(x)= 110.19791428742613
# differential_evolution step 965: f(x)= 110.19791428742613
# differential_evolution step 966: f(x)= 110.19791428742613
# differential_evolution step 967: f(x)= 110.19791428742613
# differential_evolution step 968: f(x)= 110.19791428742613
# differential_evolution step 969: f(x)= 110.19791428742613
# differential_evolution step 970: f(x)= 110.19791428742613
# differential_evolution step 971: f(x)= 110.19791428742613
# differential_evolution step 972: f(x)= 110.19791428742613
# differential_evolution step 973: f(x)= 110.19791428742613
# differential_evolution step 974: f(x)= 110.19791428742613
# differential_evolution step 975: f(x)= 110.19791428742613
# differential_evolution step 976: f(x)= 110.19791428742613
# differential_evolution step 977: f(x)= 110.19791428742613
# differential_evolution step 978: f(x)= 110.19791428742613
# differential_evolution step 979: f(x)= 110.19791428742613
# differential_evolution step 980: f(x)= 110.19791428742613
# differential_evolution step 981: f(x)= 110.19791428742613
# differential_evolution step 982: f(x)= 110.19791428742613
# differential_evolution step 983: f(x)= 110.19791428742613
# differential_evolution step 984: f(x)= 110.19791428742613
# differential_evolution step 985: f(x)= 110.19791428742613
# differential_evolution step 986: f(x)= 110.19791428742613
# differential_evolution step 987: f(x)= 110.19791428742613
# differential_evolution step 988: f(x)= 110.19791428742613
# differential_evolution step 989: f(x)= 110.19791428742613
# differential_evolution step 990: f(x)= 110.19791428742613
# differential_evolution step 991: f(x)= 110.19791428742613
# differential_evolution step 992: f(x)= 110.19791428742613
# differential_evolution step 993: f(x)= 110.19791428742613
# differential_evolution step 994: f(x)= 110.19791428742613
# differential_evolution step 995: f(x)= 109.48546868596813
# differential_evolution step 996: f(x)= 109.48546868596813
# differential_evolution step 997: f(x)= 109.48546868596813
# differential_evolution step 998: f(x)= 109.48546868596813
# differential_evolution step 999: f(x)= 109.48546868596813
# differential_evolution step 1000: f(x)= 109.48546868596813
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17704\68776662.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.1155, r_e=8.3744, n=2.4176, x_0=16.7774
# Sérsic 2: I_e=2.7449, r_e=4.8895, n=3.0754, x_0=41.6152
# Sérsic 3: I_e=8.1185, r_e=6.2744, n=0.7696, x_0=60.5988
# Sérsic 4: I_e=7.9954, r_e=4.7782, n=1.0563, x_0=65.7019
# Sérsic 5: I_e=6.1515, r_e=4.7517, n=1.5019, x_0=72.5517
# Sérsic 6: I_e=1.0943, r_e=8.1261, n=1.1679, x_0=91.0623
# Chi quadro minimo: 92.17477243725068
# False

# %%
plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, 
                                           p0=result.x, sigma = radial_profile_error_HA, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, radial_profile_error_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.0491, r_e=8.2235, n=2.4864, x_0=16.6898
# Sérsic 2: I_e=2.7264, r_e=4.9769, n=3.0521, x_0=41.6152
# Sérsic 3: I_e=8.1193, r_e=6.3395, n=0.7675, x_0=60.5951
# Sérsic 4: I_e=7.9941, r_e=4.7638, n=1.0552, x_0=65.6874
# Sérsic 5: I_e=6.1305, r_e=4.7127, n=1.5057, x_0=72.5644
# Sérsic 6: I_e=1.0733, r_e=8.1056, n=1.1915, x_0=91.1046
# [7.67326831e-01 1.97097710e+00 3.32148279e-01 5.06933529e-02
#  3.01461855e+00 3.02547149e+00 2.25378243e+00 2.65748122e-04
#  4.33701922e+00 7.63023968e-01 1.24825035e-01 7.02639314e-01
#  1.32564746e+01 9.22575074e+00 1.11797922e+00 2.35491306e-01
#  2.26519836e+00 2.38692555e+00 2.86228320e-01 1.35726906e-01
#  9.88348800e-01 6.11345996e+00 6.11692511e-01 2.72177122e-01]
# 27.247920267282236

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.15, x_0_HA[0]+1.15),   # x_0: circa la posizione di Halpha

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.15, x_0_HA[1]+1.15),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.15, x_0_HA[2]+1.15),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-1.15, x_0_HA[3]+1.15),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[4]-1.15, x_0_HA[4]+1.15),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[4]-1.15, x_0_HA[4]+1.15),
    
    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[5]-1.15, x_0_HA[5]+1.15)
]

# %%
bounds
# Out:
# [(0, 10),
#  (0, 50),
#  (0.1, 10),
#  (15.539800000000001, 17.8398),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (40.4652, 42.7652),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (59.445100000000004, 61.7451),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (64.53739999999999, 66.8374),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (71.4144, 73.71440000000001),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (71.4144, 73.71440000000001),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (89.9546, 92.25460000000001)]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds = bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 118005.02522971814
# differential_evolution step 2: f(x)= 118005.02522971814
# differential_evolution step 3: f(x)= 9143.455646343122
# differential_evolution step 4: f(x)= 8564.056440110306
# differential_evolution step 5: f(x)= 8564.056440110306
# differential_evolution step 6: f(x)= 8564.056440110306
# differential_evolution step 7: f(x)= 3210.337587916651
# differential_evolution step 8: f(x)= 2276.127777885882
# differential_evolution step 9: f(x)= 2276.127777885882
# differential_evolution step 10: f(x)= 2276.127777885882
# differential_evolution step 11: f(x)= 2276.127777885882
# differential_evolution step 12: f(x)= 2276.127777885882
# differential_evolution step 13: f(x)= 2276.127777885882
# differential_evolution step 14: f(x)= 2133.7369938520183
# differential_evolution step 15: f(x)= 2133.7369938520183
# differential_evolution step 16: f(x)= 2133.7369938520183
# differential_evolution step 17: f(x)= 2133.7369938520183
# differential_evolution step 18: f(x)= 1127.2662514033502
# differential_evolution step 19: f(x)= 1127.2662514033502
# differential_evolution step 20: f(x)= 1127.2662514033502
# differential_evolution step 21: f(x)= 1127.2662514033502
# differential_evolution step 22: f(x)= 1127.2662514033502
# differential_evolution step 23: f(x)= 1045.4821364252603
# differential_evolution step 24: f(x)= 1045.4821364252603
# differential_evolution step 25: f(x)= 812.3699421663724
# differential_evolution step 26: f(x)= 812.3699421663724
# differential_evolution step 27: f(x)= 812.3699421663724
# differential_evolution step 28: f(x)= 773.8289163696909
# differential_evolution step 29: f(x)= 773.8289163696909
# differential_evolution step 30: f(x)= 773.8289163696909
# differential_evolution step 31: f(x)= 773.8289163696909
# differential_evolution step 32: f(x)= 694.5890615738081
# differential_evolution step 33: f(x)= 694.5890615738081
# differential_evolution step 34: f(x)= 694.5890615738081
# differential_evolution step 35: f(x)= 651.574307701452
# differential_evolution step 36: f(x)= 651.574307701452
# differential_evolution step 37: f(x)= 396.73099071678627
# differential_evolution step 38: f(x)= 396.73099071678627
# differential_evolution step 39: f(x)= 396.73099071678627
# differential_evolution step 40: f(x)= 396.73099071678627
# differential_evolution step 41: f(x)= 394.56245097441894
# differential_evolution step 42: f(x)= 394.56245097441894
# differential_evolution step 43: f(x)= 394.56245097441894
# differential_evolution step 44: f(x)= 394.56245097441894
# differential_evolution step 45: f(x)= 394.56245097441894
# differential_evolution step 46: f(x)= 394.56245097441894
# differential_evolution step 47: f(x)= 394.56245097441894
# differential_evolution step 48: f(x)= 394.56245097441894
# differential_evolution step 49: f(x)= 394.56245097441894
# differential_evolution step 50: f(x)= 394.56245097441894
# differential_evolution step 51: f(x)= 394.56245097441894
# differential_evolution step 52: f(x)= 394.56245097441894
# differential_evolution step 53: f(x)= 394.56245097441894
# differential_evolution step 54: f(x)= 394.56245097441894
# differential_evolution step 55: f(x)= 394.56245097441894
# differential_evolution step 56: f(x)= 394.56245097441894
# differential_evolution step 57: f(x)= 394.56245097441894
# differential_evolution step 58: f(x)= 394.56245097441894
# differential_evolution step 59: f(x)= 394.56245097441894
# differential_evolution step 60: f(x)= 394.56245097441894
# differential_evolution step 61: f(x)= 394.56245097441894
# differential_evolution step 62: f(x)= 394.56245097441894
# differential_evolution step 63: f(x)= 394.56245097441894
# differential_evolution step 64: f(x)= 359.49670800976344
# differential_evolution step 65: f(x)= 359.49670800976344
# differential_evolution step 66: f(x)= 359.49670800976344
# differential_evolution step 67: f(x)= 309.6744205185247
# differential_evolution step 68: f(x)= 214.69605269232363
# differential_evolution step 69: f(x)= 214.69605269232363
# differential_evolution step 70: f(x)= 214.69605269232363
# differential_evolution step 71: f(x)= 214.69605269232363
# differential_evolution step 72: f(x)= 214.69605269232363
# differential_evolution step 73: f(x)= 214.69605269232363
# differential_evolution step 74: f(x)= 214.69605269232363
# differential_evolution step 75: f(x)= 214.69605269232363
# differential_evolution step 76: f(x)= 214.69605269232363
# differential_evolution step 77: f(x)= 214.69605269232363
# differential_evolution step 78: f(x)= 214.69605269232363
# differential_evolution step 79: f(x)= 193.7194286216078
# differential_evolution step 80: f(x)= 193.7194286216078
# differential_evolution step 81: f(x)= 193.7194286216078
# differential_evolution step 82: f(x)= 193.7194286216078
# differential_evolution step 83: f(x)= 193.7194286216078
# differential_evolution step 84: f(x)= 193.7194286216078
# differential_evolution step 85: f(x)= 193.7194286216078
# differential_evolution step 86: f(x)= 193.7194286216078
# differential_evolution step 87: f(x)= 183.48069906542867
# differential_evolution step 88: f(x)= 148.13055190702136
# differential_evolution step 89: f(x)= 148.13055190702136
# differential_evolution step 90: f(x)= 148.13055190702136
# differential_evolution step 91: f(x)= 148.13055190702136
# differential_evolution step 92: f(x)= 148.13055190702136
# differential_evolution step 93: f(x)= 148.13055190702136
# differential_evolution step 94: f(x)= 143.39253929057708
# differential_evolution step 95: f(x)= 143.39253929057708
# differential_evolution step 96: f(x)= 143.39253929057708
# differential_evolution step 97: f(x)= 143.39253929057708
# differential_evolution step 98: f(x)= 133.80842917258795
# differential_evolution step 99: f(x)= 133.80842917258795
# differential_evolution step 100: f(x)= 133.80842917258795
# differential_evolution step 101: f(x)= 133.80842917258795
# differential_evolution step 102: f(x)= 133.80842917258795
# differential_evolution step 103: f(x)= 133.80842917258795
# differential_evolution step 104: f(x)= 133.80842917258795
# differential_evolution step 105: f(x)= 133.80842917258795
# differential_evolution step 106: f(x)= 133.80842917258795
# differential_evolution step 107: f(x)= 133.80842917258795
# differential_evolution step 108: f(x)= 133.80842917258795
# differential_evolution step 109: f(x)= 133.80842917258795
# differential_evolution step 110: f(x)= 133.80842917258795
# differential_evolution step 111: f(x)= 133.80842917258795
# differential_evolution step 112: f(x)= 133.80842917258795
# differential_evolution step 113: f(x)= 133.80842917258795
# differential_evolution step 114: f(x)= 133.80842917258795
# differential_evolution step 115: f(x)= 133.80842917258795
# differential_evolution step 116: f(x)= 89.49261865835203
# differential_evolution step 117: f(x)= 89.49261865835203
# differential_evolution step 118: f(x)= 89.49261865835203
# differential_evolution step 119: f(x)= 89.49261865835203
# differential_evolution step 120: f(x)= 89.49261865835203
# differential_evolution step 121: f(x)= 89.49261865835203
# differential_evolution step 122: f(x)= 89.49261865835203
# differential_evolution step 123: f(x)= 87.27385866769626
# differential_evolution step 124: f(x)= 87.27385866769626
# differential_evolution step 125: f(x)= 87.27385866769626
# differential_evolution step 126: f(x)= 87.27385866769626
# differential_evolution step 127: f(x)= 87.27385866769626
# differential_evolution step 128: f(x)= 87.27385866769626
# differential_evolution step 129: f(x)= 87.27385866769626
# differential_evolution step 130: f(x)= 87.27385866769626
# differential_evolution step 131: f(x)= 87.27385866769626
# differential_evolution step 132: f(x)= 73.13602275013322
# differential_evolution step 133: f(x)= 73.13602275013322
# differential_evolution step 134: f(x)= 73.13602275013322
# differential_evolution step 135: f(x)= 73.13602275013322
# differential_evolution step 136: f(x)= 73.13602275013322
# differential_evolution step 137: f(x)= 73.13602275013322
# differential_evolution step 138: f(x)= 73.13602275013322
# differential_evolution step 139: f(x)= 73.13602275013322
# differential_evolution step 140: f(x)= 73.13602275013322
# differential_evolution step 141: f(x)= 73.13602275013322
# differential_evolution step 142: f(x)= 73.13602275013322
# differential_evolution step 143: f(x)= 73.13602275013322
# differential_evolution step 144: f(x)= 73.13602275013322
# differential_evolution step 145: f(x)= 73.13602275013322
# differential_evolution step 146: f(x)= 73.13602275013322
# differential_evolution step 147: f(x)= 73.13602275013322
# differential_evolution step 148: f(x)= 73.13602275013322
# differential_evolution step 149: f(x)= 73.13602275013322
# differential_evolution step 150: f(x)= 73.13602275013322
# differential_evolution step 151: f(x)= 73.13602275013322
# differential_evolution step 152: f(x)= 73.13602275013322
# differential_evolution step 153: f(x)= 73.13602275013322
# differential_evolution step 154: f(x)= 73.13602275013322
# differential_evolution step 155: f(x)= 73.13602275013322
# differential_evolution step 156: f(x)= 73.13602275013322
# differential_evolution step 157: f(x)= 73.13602275013322
# differential_evolution step 158: f(x)= 73.13602275013322
# differential_evolution step 159: f(x)= 73.13602275013322
# differential_evolution step 160: f(x)= 63.62213677468489
# differential_evolution step 161: f(x)= 63.62213677468489
# differential_evolution step 162: f(x)= 63.62213677468489
# differential_evolution step 163: f(x)= 63.62213677468489
# differential_evolution step 164: f(x)= 63.62213677468489
# differential_evolution step 165: f(x)= 63.62213677468489
# differential_evolution step 166: f(x)= 63.62213677468489
# differential_evolution step 167: f(x)= 63.62213677468489
# differential_evolution step 168: f(x)= 61.44536803803083
# differential_evolution step 169: f(x)= 61.44536803803083
# differential_evolution step 170: f(x)= 61.44536803803083
# differential_evolution step 171: f(x)= 61.44536803803083
# differential_evolution step 172: f(x)= 61.44536803803083
# differential_evolution step 173: f(x)= 61.44536803803083
# differential_evolution step 174: f(x)= 61.44536803803083
# differential_evolution step 175: f(x)= 61.44536803803083
# differential_evolution step 176: f(x)= 61.44536803803083
# differential_evolution step 177: f(x)= 61.44536803803083
# differential_evolution step 178: f(x)= 61.44536803803083
# differential_evolution step 179: f(x)= 61.44536803803083
# differential_evolution step 180: f(x)= 61.44536803803083
# differential_evolution step 181: f(x)= 61.44536803803083
# differential_evolution step 182: f(x)= 61.44536803803083
# differential_evolution step 183: f(x)= 61.44536803803083
# differential_evolution step 184: f(x)= 61.44536803803083
# differential_evolution step 185: f(x)= 61.44536803803083
# differential_evolution step 186: f(x)= 61.44536803803083
# differential_evolution step 187: f(x)= 61.44536803803083
# differential_evolution step 188: f(x)= 61.44536803803083
# differential_evolution step 189: f(x)= 61.44536803803083
# differential_evolution step 190: f(x)= 61.44536803803083
# differential_evolution step 191: f(x)= 61.44536803803083
# differential_evolution step 192: f(x)= 61.44536803803083
# differential_evolution step 193: f(x)= 61.44536803803083
# differential_evolution step 194: f(x)= 57.685196224305265
# differential_evolution step 195: f(x)= 52.82093679318405
# differential_evolution step 196: f(x)= 52.82093679318405
# differential_evolution step 197: f(x)= 52.82093679318405
# differential_evolution step 198: f(x)= 52.82093679318405
# differential_evolution step 199: f(x)= 52.82093679318405
# differential_evolution step 200: f(x)= 46.24159920880688
# differential_evolution step 201: f(x)= 46.24159920880688
# differential_evolution step 202: f(x)= 46.24159920880688
# differential_evolution step 203: f(x)= 46.24159920880688
# differential_evolution step 204: f(x)= 46.24159920880688
# differential_evolution step 205: f(x)= 46.24159920880688
# differential_evolution step 206: f(x)= 46.24159920880688
# differential_evolution step 207: f(x)= 46.24159920880688
# differential_evolution step 208: f(x)= 46.24159920880688
# differential_evolution step 209: f(x)= 46.24159920880688
# differential_evolution step 210: f(x)= 46.24159920880688
# differential_evolution step 211: f(x)= 46.24159920880688
# differential_evolution step 212: f(x)= 46.24159920880688
# differential_evolution step 213: f(x)= 46.24159920880688
# differential_evolution step 214: f(x)= 46.24159920880688
# differential_evolution step 215: f(x)= 46.24159920880688
# differential_evolution step 216: f(x)= 46.24159920880688
# differential_evolution step 217: f(x)= 42.180896219758246
# differential_evolution step 218: f(x)= 42.180896219758246
# differential_evolution step 219: f(x)= 42.180896219758246
# differential_evolution step 220: f(x)= 42.180896219758246
# differential_evolution step 221: f(x)= 42.180896219758246
# differential_evolution step 222: f(x)= 42.180896219758246
# differential_evolution step 223: f(x)= 42.180896219758246
# differential_evolution step 224: f(x)= 42.180896219758246
# differential_evolution step 225: f(x)= 42.180896219758246
# differential_evolution step 226: f(x)= 42.180896219758246
# differential_evolution step 227: f(x)= 42.180896219758246
# differential_evolution step 228: f(x)= 42.180896219758246
# differential_evolution step 229: f(x)= 42.180896219758246
# differential_evolution step 230: f(x)= 42.180896219758246
# differential_evolution step 231: f(x)= 42.180896219758246
# differential_evolution step 232: f(x)= 42.180896219758246
# differential_evolution step 233: f(x)= 42.180896219758246
# differential_evolution step 234: f(x)= 42.180896219758246
# differential_evolution step 235: f(x)= 42.180896219758246
# differential_evolution step 236: f(x)= 42.180896219758246
# differential_evolution step 237: f(x)= 42.180896219758246
# differential_evolution step 238: f(x)= 42.180896219758246
# differential_evolution step 239: f(x)= 42.180896219758246
# differential_evolution step 240: f(x)= 42.180896219758246
# differential_evolution step 241: f(x)= 42.180896219758246
# differential_evolution step 242: f(x)= 42.180896219758246
# differential_evolution step 243: f(x)= 42.180896219758246
# differential_evolution step 244: f(x)= 42.180896219758246
# differential_evolution step 245: f(x)= 42.180896219758246
# differential_evolution step 246: f(x)= 41.80749698822235
# differential_evolution step 247: f(x)= 41.80749698822235
# differential_evolution step 248: f(x)= 41.80749698822235
# differential_evolution step 249: f(x)= 41.80749698822235
# differential_evolution step 250: f(x)= 41.80749698822235
# differential_evolution step 251: f(x)= 41.80749698822235
# differential_evolution step 252: f(x)= 39.10111841087883
# differential_evolution step 253: f(x)= 39.10111841087883
# differential_evolution step 254: f(x)= 39.10111841087883
# differential_evolution step 255: f(x)= 39.10111841087883
# differential_evolution step 256: f(x)= 39.10111841087883
# differential_evolution step 257: f(x)= 39.10111841087883
# differential_evolution step 258: f(x)= 39.10111841087883
# differential_evolution step 259: f(x)= 39.10111841087883
# differential_evolution step 260: f(x)= 39.10111841087883
# differential_evolution step 261: f(x)= 39.10111841087883
# differential_evolution step 262: f(x)= 39.10111841087883
# differential_evolution step 263: f(x)= 39.10111841087883
# differential_evolution step 264: f(x)= 39.10111841087883
# differential_evolution step 265: f(x)= 39.10111841087883
# differential_evolution step 266: f(x)= 39.10111841087883
# differential_evolution step 267: f(x)= 39.10111841087883
# differential_evolution step 268: f(x)= 39.10111841087883
# differential_evolution step 269: f(x)= 39.10111841087883
# differential_evolution step 270: f(x)= 39.10111841087883
# differential_evolution step 271: f(x)= 39.10111841087883
# differential_evolution step 272: f(x)= 35.092865437704575
# differential_evolution step 273: f(x)= 35.092865437704575
# differential_evolution step 274: f(x)= 35.092865437704575
# differential_evolution step 275: f(x)= 35.092865437704575
# differential_evolution step 276: f(x)= 35.092865437704575
# differential_evolution step 277: f(x)= 35.092865437704575
# differential_evolution step 278: f(x)= 35.092865437704575
# differential_evolution step 279: f(x)= 35.092865437704575
# differential_evolution step 280: f(x)= 35.092865437704575
# differential_evolution step 281: f(x)= 35.092865437704575
# differential_evolution step 282: f(x)= 35.092865437704575
# differential_evolution step 283: f(x)= 35.092865437704575
# differential_evolution step 284: f(x)= 35.092865437704575
# differential_evolution step 285: f(x)= 35.092865437704575
# differential_evolution step 286: f(x)= 35.092865437704575
# differential_evolution step 287: f(x)= 35.092865437704575
# differential_evolution step 288: f(x)= 35.092865437704575
# differential_evolution step 289: f(x)= 35.092865437704575
# differential_evolution step 290: f(x)= 35.092865437704575
# differential_evolution step 291: f(x)= 35.092865437704575
# differential_evolution step 292: f(x)= 35.092865437704575
# differential_evolution step 293: f(x)= 35.092865437704575
# differential_evolution step 294: f(x)= 35.092865437704575
# differential_evolution step 295: f(x)= 35.092865437704575
# differential_evolution step 296: f(x)= 35.092865437704575
# differential_evolution step 297: f(x)= 35.092865437704575
# differential_evolution step 298: f(x)= 35.092865437704575
# differential_evolution step 299: f(x)= 35.092865437704575
# differential_evolution step 300: f(x)= 35.092865437704575
# differential_evolution step 301: f(x)= 35.092865437704575
# differential_evolution step 302: f(x)= 34.54317810010265
# differential_evolution step 303: f(x)= 34.54317810010265
# differential_evolution step 304: f(x)= 34.54317810010265
# differential_evolution step 305: f(x)= 34.54317810010265
# differential_evolution step 306: f(x)= 34.54317810010265
# differential_evolution step 307: f(x)= 34.54317810010265
# differential_evolution step 308: f(x)= 34.54317810010265
# differential_evolution step 309: f(x)= 34.54317810010265
# differential_evolution step 310: f(x)= 34.54317810010265
# differential_evolution step 311: f(x)= 34.54317810010265
# differential_evolution step 312: f(x)= 34.54317810010265
# differential_evolution step 313: f(x)= 34.54317810010265
# differential_evolution step 314: f(x)= 34.54317810010265
# differential_evolution step 315: f(x)= 34.54317810010265
# differential_evolution step 316: f(x)= 34.54317810010265
# differential_evolution step 317: f(x)= 34.54317810010265
# differential_evolution step 318: f(x)= 34.54317810010265
# differential_evolution step 319: f(x)= 34.54317810010265
# differential_evolution step 320: f(x)= 34.54317810010265
# differential_evolution step 321: f(x)= 34.54317810010265
# differential_evolution step 322: f(x)= 34.54317810010265
# differential_evolution step 323: f(x)= 34.54317810010265
# differential_evolution step 324: f(x)= 34.54317810010265
# differential_evolution step 325: f(x)= 34.54317810010265
# differential_evolution step 326: f(x)= 34.54317810010265
# differential_evolution step 327: f(x)= 34.54317810010265
# differential_evolution step 328: f(x)= 34.54317810010265
# differential_evolution step 329: f(x)= 34.54317810010265
# differential_evolution step 330: f(x)= 32.074292165271714
# differential_evolution step 331: f(x)= 32.074292165271714
# differential_evolution step 332: f(x)= 32.074292165271714
# differential_evolution step 333: f(x)= 32.074292165271714
# differential_evolution step 334: f(x)= 32.074292165271714
# differential_evolution step 335: f(x)= 32.074292165271714
# differential_evolution step 336: f(x)= 32.074292165271714
# differential_evolution step 337: f(x)= 32.074292165271714
# differential_evolution step 338: f(x)= 32.074292165271714
# differential_evolution step 339: f(x)= 32.074292165271714
# differential_evolution step 340: f(x)= 32.074292165271714
# differential_evolution step 341: f(x)= 32.074292165271714
# differential_evolution step 342: f(x)= 32.074292165271714
# differential_evolution step 343: f(x)= 32.074292165271714
# differential_evolution step 344: f(x)= 32.074292165271714
# differential_evolution step 345: f(x)= 32.074292165271714
# differential_evolution step 346: f(x)= 32.074292165271714
# differential_evolution step 347: f(x)= 32.074292165271714
# differential_evolution step 348: f(x)= 32.074292165271714
# differential_evolution step 349: f(x)= 32.074292165271714
# differential_evolution step 350: f(x)= 32.074292165271714
# differential_evolution step 351: f(x)= 32.074292165271714
# differential_evolution step 352: f(x)= 32.074292165271714
# differential_evolution step 353: f(x)= 32.074292165271714
# differential_evolution step 354: f(x)= 32.074292165271714
# differential_evolution step 355: f(x)= 32.074292165271714
# differential_evolution step 356: f(x)= 32.074292165271714
# differential_evolution step 357: f(x)= 32.074292165271714
# differential_evolution step 358: f(x)= 32.074292165271714
# differential_evolution step 359: f(x)= 32.074292165271714
# differential_evolution step 360: f(x)= 32.074292165271714
# differential_evolution step 361: f(x)= 32.074292165271714
# differential_evolution step 362: f(x)= 32.074292165271714
# differential_evolution step 363: f(x)= 32.074292165271714
# differential_evolution step 364: f(x)= 32.074292165271714
# differential_evolution step 365: f(x)= 32.074292165271714
# differential_evolution step 366: f(x)= 32.074292165271714
# differential_evolution step 367: f(x)= 32.074292165271714
# differential_evolution step 368: f(x)= 32.074292165271714
# differential_evolution step 369: f(x)= 32.074292165271714
# differential_evolution step 370: f(x)= 32.074292165271714
# differential_evolution step 371: f(x)= 32.074292165271714
# differential_evolution step 372: f(x)= 32.074292165271714
# differential_evolution step 373: f(x)= 32.074292165271714
# differential_evolution step 374: f(x)= 32.074292165271714
# differential_evolution step 375: f(x)= 32.074292165271714
# differential_evolution step 376: f(x)= 32.074292165271714
# differential_evolution step 377: f(x)= 32.074292165271714
# differential_evolution step 378: f(x)= 32.074292165271714
# differential_evolution step 379: f(x)= 32.074292165271714
# differential_evolution step 380: f(x)= 32.074292165271714
# differential_evolution step 381: f(x)= 32.074292165271714
# differential_evolution step 382: f(x)= 32.074292165271714
# differential_evolution step 383: f(x)= 32.074292165271714
# differential_evolution step 384: f(x)= 32.074292165271714
# differential_evolution step 385: f(x)= 26.264899175020062
# differential_evolution step 386: f(x)= 26.264899175020062
# differential_evolution step 387: f(x)= 26.264899175020062
# differential_evolution step 388: f(x)= 26.264899175020062
# differential_evolution step 389: f(x)= 26.264899175020062
# differential_evolution step 390: f(x)= 26.264899175020062
# differential_evolution step 391: f(x)= 26.264899175020062
# differential_evolution step 392: f(x)= 26.264899175020062
# differential_evolution step 393: f(x)= 26.264899175020062
# differential_evolution step 394: f(x)= 26.264899175020062
# differential_evolution step 395: f(x)= 26.264899175020062
# differential_evolution step 396: f(x)= 26.264899175020062
# differential_evolution step 397: f(x)= 26.264899175020062
# differential_evolution step 398: f(x)= 26.264899175020062
# differential_evolution step 399: f(x)= 26.264899175020062
# differential_evolution step 400: f(x)= 26.264899175020062
# differential_evolution step 401: f(x)= 26.264899175020062
# differential_evolution step 402: f(x)= 26.264899175020062
# differential_evolution step 403: f(x)= 26.264899175020062
# differential_evolution step 404: f(x)= 26.264899175020062
# differential_evolution step 405: f(x)= 26.264899175020062
# differential_evolution step 406: f(x)= 26.264899175020062
# differential_evolution step 407: f(x)= 26.264899175020062
# differential_evolution step 408: f(x)= 26.264899175020062
# differential_evolution step 409: f(x)= 26.264899175020062
# differential_evolution step 410: f(x)= 26.264899175020062
# differential_evolution step 411: f(x)= 26.264899175020062
# differential_evolution step 412: f(x)= 26.264899175020062
# differential_evolution step 413: f(x)= 26.264899175020062
# differential_evolution step 414: f(x)= 26.264899175020062
# differential_evolution step 415: f(x)= 26.264899175020062
# differential_evolution step 416: f(x)= 26.264899175020062
# differential_evolution step 417: f(x)= 26.264899175020062
# differential_evolution step 418: f(x)= 26.264899175020062
# differential_evolution step 419: f(x)= 26.264899175020062
# differential_evolution step 420: f(x)= 26.264899175020062
# differential_evolution step 421: f(x)= 26.264899175020062
# differential_evolution step 422: f(x)= 26.264899175020062
# differential_evolution step 423: f(x)= 26.264899175020062
# differential_evolution step 424: f(x)= 26.264899175020062
# differential_evolution step 425: f(x)= 26.264899175020062
# differential_evolution step 426: f(x)= 26.264899175020062
# differential_evolution step 427: f(x)= 26.264899175020062
# differential_evolution step 428: f(x)= 26.264899175020062
# differential_evolution step 429: f(x)= 26.264899175020062
# differential_evolution step 430: f(x)= 26.264899175020062
# differential_evolution step 431: f(x)= 26.264899175020062
# differential_evolution step 432: f(x)= 26.264899175020062
# differential_evolution step 433: f(x)= 26.264899175020062
# differential_evolution step 434: f(x)= 26.264899175020062
# differential_evolution step 435: f(x)= 26.264899175020062
# differential_evolution step 436: f(x)= 25.17655069159904
# differential_evolution step 437: f(x)= 25.17655069159904
# differential_evolution step 438: f(x)= 25.17655069159904
# differential_evolution step 439: f(x)= 25.17655069159904
# differential_evolution step 440: f(x)= 25.17655069159904
# differential_evolution step 441: f(x)= 25.17655069159904
# differential_evolution step 442: f(x)= 25.17655069159904
# differential_evolution step 443: f(x)= 25.17655069159904
# differential_evolution step 444: f(x)= 25.17655069159904
# differential_evolution step 445: f(x)= 25.17655069159904
# differential_evolution step 446: f(x)= 25.17655069159904
# differential_evolution step 447: f(x)= 25.17655069159904
# differential_evolution step 448: f(x)= 25.17655069159904
# differential_evolution step 449: f(x)= 25.17655069159904
# differential_evolution step 450: f(x)= 25.17655069159904
# differential_evolution step 451: f(x)= 25.17655069159904
# differential_evolution step 452: f(x)= 25.17655069159904
# differential_evolution step 453: f(x)= 25.17655069159904
# differential_evolution step 454: f(x)= 25.17655069159904
# differential_evolution step 455: f(x)= 25.17655069159904
# differential_evolution step 456: f(x)= 25.17655069159904
# differential_evolution step 457: f(x)= 25.17655069159904
# differential_evolution step 458: f(x)= 25.17655069159904
# differential_evolution step 459: f(x)= 25.17655069159904
# differential_evolution step 460: f(x)= 25.17655069159904
# differential_evolution step 461: f(x)= 25.17655069159904
# differential_evolution step 462: f(x)= 25.17655069159904
# differential_evolution step 463: f(x)= 25.17655069159904
# differential_evolution step 464: f(x)= 25.17655069159904
# differential_evolution step 465: f(x)= 25.17655069159904
# differential_evolution step 466: f(x)= 25.17655069159904
# differential_evolution step 467: f(x)= 25.17655069159904
# differential_evolution step 468: f(x)= 25.17655069159904
# differential_evolution step 469: f(x)= 25.17655069159904
# differential_evolution step 470: f(x)= 25.17655069159904
# differential_evolution step 471: f(x)= 25.17655069159904
# differential_evolution step 472: f(x)= 25.17655069159904
# differential_evolution step 473: f(x)= 25.17655069159904
# differential_evolution step 474: f(x)= 25.17655069159904
# differential_evolution step 475: f(x)= 25.17655069159904
# differential_evolution step 476: f(x)= 25.17655069159904
# differential_evolution step 477: f(x)= 25.17655069159904
# differential_evolution step 478: f(x)= 25.17655069159904
# differential_evolution step 479: f(x)= 25.17655069159904
# differential_evolution step 480: f(x)= 25.17655069159904
# differential_evolution step 481: f(x)= 25.17655069159904
# differential_evolution step 482: f(x)= 25.17655069159904
# differential_evolution step 483: f(x)= 25.17655069159904
# differential_evolution step 484: f(x)= 25.17655069159904
# differential_evolution step 485: f(x)= 25.17655069159904
# differential_evolution step 486: f(x)= 25.17655069159904
# differential_evolution step 487: f(x)= 25.17655069159904
# differential_evolution step 488: f(x)= 25.17655069159904
# differential_evolution step 489: f(x)= 25.17655069159904
# differential_evolution step 490: f(x)= 25.17655069159904
# differential_evolution step 491: f(x)= 25.17655069159904
# differential_evolution step 492: f(x)= 25.17655069159904
# differential_evolution step 493: f(x)= 25.17655069159904
# differential_evolution step 494: f(x)= 25.17655069159904
# differential_evolution step 495: f(x)= 25.17655069159904
# differential_evolution step 496: f(x)= 25.147329144870337
# differential_evolution step 497: f(x)= 25.147329144870337
# differential_evolution step 498: f(x)= 25.147329144870337
# differential_evolution step 499: f(x)= 25.147329144870337
# differential_evolution step 500: f(x)= 25.147329144870337
# differential_evolution step 501: f(x)= 25.147329144870337
# differential_evolution step 502: f(x)= 25.147329144870337
# differential_evolution step 503: f(x)= 25.147329144870337
# differential_evolution step 504: f(x)= 25.147329144870337
# differential_evolution step 505: f(x)= 25.147329144870337
# differential_evolution step 506: f(x)= 25.147329144870337
# differential_evolution step 507: f(x)= 25.147329144870337
# differential_evolution step 508: f(x)= 23.93875234343661
# differential_evolution step 509: f(x)= 23.93875234343661
# differential_evolution step 510: f(x)= 23.93875234343661
# differential_evolution step 511: f(x)= 23.93875234343661
# differential_evolution step 512: f(x)= 23.93875234343661
# differential_evolution step 513: f(x)= 23.93875234343661
# differential_evolution step 514: f(x)= 23.93875234343661
# differential_evolution step 515: f(x)= 23.93875234343661
# differential_evolution step 516: f(x)= 23.93875234343661
# differential_evolution step 517: f(x)= 23.93875234343661
# differential_evolution step 518: f(x)= 23.93875234343661
# differential_evolution step 519: f(x)= 23.93875234343661
# differential_evolution step 520: f(x)= 23.93875234343661
# differential_evolution step 521: f(x)= 23.93875234343661
# differential_evolution step 522: f(x)= 23.93875234343661
# differential_evolution step 523: f(x)= 23.93875234343661
# differential_evolution step 524: f(x)= 23.93875234343661
# differential_evolution step 525: f(x)= 23.93875234343661
# differential_evolution step 526: f(x)= 23.93875234343661
# differential_evolution step 527: f(x)= 23.93875234343661
# differential_evolution step 528: f(x)= 23.72989709429779
# differential_evolution step 529: f(x)= 23.72989709429779
# differential_evolution step 530: f(x)= 23.72989709429779
# differential_evolution step 531: f(x)= 23.72989709429779
# differential_evolution step 532: f(x)= 23.72989709429779
# differential_evolution step 533: f(x)= 23.72989709429779
# differential_evolution step 534: f(x)= 23.72989709429779
# differential_evolution step 535: f(x)= 23.72989709429779
# differential_evolution step 536: f(x)= 23.72989709429779
# differential_evolution step 537: f(x)= 23.72989709429779
# differential_evolution step 538: f(x)= 23.72989709429779
# differential_evolution step 539: f(x)= 23.72989709429779
# differential_evolution step 540: f(x)= 23.15620786491796
# differential_evolution step 541: f(x)= 23.15620786491796
# differential_evolution step 542: f(x)= 23.15620786491796
# differential_evolution step 543: f(x)= 23.15620786491796
# differential_evolution step 544: f(x)= 23.15620786491796
# differential_evolution step 545: f(x)= 23.15620786491796
# differential_evolution step 546: f(x)= 23.15620786491796
# differential_evolution step 547: f(x)= 23.15620786491796
# differential_evolution step 548: f(x)= 23.15620786491796
# differential_evolution step 549: f(x)= 23.15620786491796
# differential_evolution step 550: f(x)= 23.15620786491796
# differential_evolution step 551: f(x)= 23.15620786491796
# differential_evolution step 552: f(x)= 23.15620786491796
# differential_evolution step 553: f(x)= 23.15620786491796
# differential_evolution step 554: f(x)= 23.15620786491796
# differential_evolution step 555: f(x)= 23.15620786491796
# differential_evolution step 556: f(x)= 23.15620786491796
# differential_evolution step 557: f(x)= 23.15620786491796
# differential_evolution step 558: f(x)= 23.15620786491796
# differential_evolution step 559: f(x)= 23.15620786491796
# differential_evolution step 560: f(x)= 23.15620786491796
# differential_evolution step 561: f(x)= 23.15620786491796
# differential_evolution step 562: f(x)= 23.15620786491796
# differential_evolution step 563: f(x)= 23.15620786491796
# differential_evolution step 564: f(x)= 23.15620786491796
# differential_evolution step 565: f(x)= 23.15620786491796
# differential_evolution step 566: f(x)= 23.15620786491796
# differential_evolution step 567: f(x)= 23.15620786491796
# differential_evolution step 568: f(x)= 21.939073490562766
# differential_evolution step 569: f(x)= 21.939073490562766
# differential_evolution step 570: f(x)= 21.939073490562766
# differential_evolution step 571: f(x)= 21.939073490562766
# differential_evolution step 572: f(x)= 21.939073490562766
# differential_evolution step 573: f(x)= 21.939073490562766
# differential_evolution step 574: f(x)= 21.939073490562766
# differential_evolution step 575: f(x)= 21.939073490562766
# differential_evolution step 576: f(x)= 21.86408019599064
# differential_evolution step 577: f(x)= 21.86408019599064
# differential_evolution step 578: f(x)= 21.86408019599064
# differential_evolution step 579: f(x)= 21.86408019599064
# differential_evolution step 580: f(x)= 21.86408019599064
# differential_evolution step 581: f(x)= 21.86408019599064
# differential_evolution step 582: f(x)= 21.86408019599064
# differential_evolution step 583: f(x)= 21.86408019599064
# differential_evolution step 584: f(x)= 21.86408019599064
# differential_evolution step 585: f(x)= 21.86408019599064
# differential_evolution step 586: f(x)= 21.86408019599064
# differential_evolution step 587: f(x)= 21.86408019599064
# differential_evolution step 588: f(x)= 21.86408019599064
# differential_evolution step 589: f(x)= 21.86408019599064
# differential_evolution step 590: f(x)= 21.86408019599064
# differential_evolution step 591: f(x)= 21.416078558644287
# differential_evolution step 592: f(x)= 21.416078558644287
# differential_evolution step 593: f(x)= 21.416078558644287
# differential_evolution step 594: f(x)= 21.416078558644287
# differential_evolution step 595: f(x)= 21.416078558644287
# differential_evolution step 596: f(x)= 21.416078558644287
# differential_evolution step 597: f(x)= 21.416078558644287
# differential_evolution step 598: f(x)= 21.416078558644287
# differential_evolution step 599: f(x)= 21.416078558644287
# differential_evolution step 600: f(x)= 21.416078558644287
# differential_evolution step 601: f(x)= 21.416078558644287
# differential_evolution step 602: f(x)= 21.416078558644287
# differential_evolution step 603: f(x)= 21.416078558644287
# differential_evolution step 604: f(x)= 21.416078558644287
# differential_evolution step 605: f(x)= 21.416078558644287
# differential_evolution step 606: f(x)= 21.416078558644287
# differential_evolution step 607: f(x)= 21.416078558644287
# differential_evolution step 608: f(x)= 21.416078558644287
# differential_evolution step 609: f(x)= 21.416078558644287
# differential_evolution step 610: f(x)= 21.416078558644287
# differential_evolution step 611: f(x)= 21.416078558644287
# differential_evolution step 612: f(x)= 21.416078558644287
# differential_evolution step 613: f(x)= 21.416078558644287
# differential_evolution step 614: f(x)= 21.416078558644287
# differential_evolution step 615: f(x)= 21.416078558644287
# differential_evolution step 616: f(x)= 21.416078558644287
# differential_evolution step 617: f(x)= 21.416078558644287
# differential_evolution step 618: f(x)= 21.416078558644287
# differential_evolution step 619: f(x)= 21.416078558644287
# differential_evolution step 620: f(x)= 21.416078558644287
# differential_evolution step 621: f(x)= 21.416078558644287
# differential_evolution step 622: f(x)= 21.416078558644287
# differential_evolution step 623: f(x)= 21.416078558644287
# differential_evolution step 624: f(x)= 21.416078558644287
# differential_evolution step 625: f(x)= 21.416078558644287
# differential_evolution step 626: f(x)= 21.416078558644287
# differential_evolution step 627: f(x)= 21.416078558644287
# differential_evolution step 628: f(x)= 21.416078558644287
# differential_evolution step 629: f(x)= 21.416078558644287
# differential_evolution step 630: f(x)= 21.416078558644287
# differential_evolution step 631: f(x)= 21.416078558644287
# differential_evolution step 632: f(x)= 21.416078558644287
# differential_evolution step 633: f(x)= 21.416078558644287
# differential_evolution step 634: f(x)= 20.543321260627366
# differential_evolution step 635: f(x)= 20.543321260627366
# differential_evolution step 636: f(x)= 20.543321260627366
# differential_evolution step 637: f(x)= 20.543321260627366
# differential_evolution step 638: f(x)= 20.543321260627366
# differential_evolution step 639: f(x)= 20.543321260627366
# differential_evolution step 640: f(x)= 20.543321260627366
# differential_evolution step 641: f(x)= 20.543321260627366
# differential_evolution step 642: f(x)= 20.543321260627366
# differential_evolution step 643: f(x)= 20.543321260627366
# differential_evolution step 644: f(x)= 20.543321260627366
# differential_evolution step 645: f(x)= 20.543321260627366
# differential_evolution step 646: f(x)= 20.543321260627366
# differential_evolution step 647: f(x)= 20.543321260627366
# differential_evolution step 648: f(x)= 20.543321260627366
# differential_evolution step 649: f(x)= 19.83525845063978
# differential_evolution step 650: f(x)= 19.83525845063978
# differential_evolution step 651: f(x)= 19.83525845063978
# differential_evolution step 652: f(x)= 19.83525845063978
# differential_evolution step 653: f(x)= 19.83525845063978
# differential_evolution step 654: f(x)= 18.914479051174453
# differential_evolution step 655: f(x)= 18.914479051174453
# differential_evolution step 656: f(x)= 18.914479051174453
# differential_evolution step 657: f(x)= 18.914479051174453
# differential_evolution step 658: f(x)= 18.914479051174453
# differential_evolution step 659: f(x)= 18.914479051174453
# differential_evolution step 660: f(x)= 18.914479051174453
# differential_evolution step 661: f(x)= 18.914479051174453
# differential_evolution step 662: f(x)= 18.914479051174453
# differential_evolution step 663: f(x)= 18.914479051174453
# differential_evolution step 664: f(x)= 18.914479051174453
# differential_evolution step 665: f(x)= 18.914479051174453
# differential_evolution step 666: f(x)= 18.914479051174453
# differential_evolution step 667: f(x)= 18.914479051174453
# differential_evolution step 668: f(x)= 18.914479051174453
# differential_evolution step 669: f(x)= 18.914479051174453
# differential_evolution step 670: f(x)= 18.914479051174453
# differential_evolution step 671: f(x)= 18.914479051174453
# differential_evolution step 672: f(x)= 18.38592210695763
# differential_evolution step 673: f(x)= 18.38592210695763
# differential_evolution step 674: f(x)= 18.38592210695763
# differential_evolution step 675: f(x)= 18.38592210695763
# differential_evolution step 676: f(x)= 18.38592210695763
# differential_evolution step 677: f(x)= 18.38592210695763
# differential_evolution step 678: f(x)= 18.38592210695763
# differential_evolution step 679: f(x)= 18.38592210695763
# differential_evolution step 680: f(x)= 18.38592210695763
# differential_evolution step 681: f(x)= 18.38592210695763
# differential_evolution step 682: f(x)= 18.38592210695763
# differential_evolution step 683: f(x)= 18.38592210695763
# differential_evolution step 684: f(x)= 18.38592210695763
# differential_evolution step 685: f(x)= 18.38592210695763
# differential_evolution step 686: f(x)= 18.38592210695763
# differential_evolution step 687: f(x)= 18.38592210695763
# differential_evolution step 688: f(x)= 18.38592210695763
# differential_evolution step 689: f(x)= 18.38592210695763
# differential_evolution step 690: f(x)= 18.38592210695763
# differential_evolution step 691: f(x)= 18.38592210695763
# differential_evolution step 692: f(x)= 18.38592210695763
# differential_evolution step 693: f(x)= 18.38592210695763
# differential_evolution step 694: f(x)= 18.38592210695763
# differential_evolution step 695: f(x)= 18.38592210695763
# differential_evolution step 696: f(x)= 18.38592210695763
# differential_evolution step 697: f(x)= 18.38592210695763
# differential_evolution step 698: f(x)= 18.38592210695763
# differential_evolution step 699: f(x)= 18.38592210695763
# differential_evolution step 700: f(x)= 18.38592210695763
# differential_evolution step 701: f(x)= 18.38592210695763
# differential_evolution step 702: f(x)= 18.38592210695763
# differential_evolution step 703: f(x)= 18.38592210695763
# differential_evolution step 704: f(x)= 18.38592210695763
# differential_evolution step 705: f(x)= 18.38592210695763
# differential_evolution step 706: f(x)= 18.38592210695763
# differential_evolution step 707: f(x)= 18.38592210695763
# differential_evolution step 708: f(x)= 18.38592210695763
# differential_evolution step 709: f(x)= 18.38592210695763
# differential_evolution step 710: f(x)= 18.38592210695763
# differential_evolution step 711: f(x)= 18.38592210695763
# differential_evolution step 712: f(x)= 18.38592210695763
# differential_evolution step 713: f(x)= 18.38592210695763
# differential_evolution step 714: f(x)= 18.38592210695763
# differential_evolution step 715: f(x)= 18.38592210695763
# differential_evolution step 716: f(x)= 18.38592210695763
# differential_evolution step 717: f(x)= 18.38592210695763
# differential_evolution step 718: f(x)= 18.38592210695763
# differential_evolution step 719: f(x)= 18.38592210695763
# differential_evolution step 720: f(x)= 18.38592210695763
# differential_evolution step 721: f(x)= 18.38592210695763
# differential_evolution step 722: f(x)= 18.38592210695763
# differential_evolution step 723: f(x)= 18.38592210695763
# differential_evolution step 724: f(x)= 18.38592210695763
# differential_evolution step 725: f(x)= 18.38592210695763
# differential_evolution step 726: f(x)= 18.38592210695763
# differential_evolution step 727: f(x)= 18.38592210695763
# differential_evolution step 728: f(x)= 18.38592210695763
# differential_evolution step 729: f(x)= 18.38592210695763
# differential_evolution step 730: f(x)= 18.38592210695763
# differential_evolution step 731: f(x)= 18.38592210695763
# differential_evolution step 732: f(x)= 18.38592210695763
# differential_evolution step 733: f(x)= 18.38592210695763
# differential_evolution step 734: f(x)= 18.38592210695763
# differential_evolution step 735: f(x)= 18.38592210695763
# differential_evolution step 736: f(x)= 18.38592210695763
# differential_evolution step 737: f(x)= 18.38592210695763
# differential_evolution step 738: f(x)= 18.38592210695763
# differential_evolution step 739: f(x)= 18.38592210695763
# differential_evolution step 740: f(x)= 18.38592210695763
# differential_evolution step 741: f(x)= 18.38592210695763
# differential_evolution step 742: f(x)= 18.38592210695763
# differential_evolution step 743: f(x)= 18.38592210695763
# differential_evolution step 744: f(x)= 18.38592210695763
# differential_evolution step 745: f(x)= 18.38592210695763
# differential_evolution step 746: f(x)= 18.38592210695763
# differential_evolution step 747: f(x)= 18.38592210695763
# differential_evolution step 748: f(x)= 18.38592210695763
# differential_evolution step 749: f(x)= 18.38592210695763
# differential_evolution step 750: f(x)= 18.38592210695763
# differential_evolution step 751: f(x)= 18.38592210695763
# differential_evolution step 752: f(x)= 18.38592210695763
# differential_evolution step 753: f(x)= 18.38592210695763
# differential_evolution step 754: f(x)= 18.38592210695763
# differential_evolution step 755: f(x)= 18.38592210695763
# differential_evolution step 756: f(x)= 18.38592210695763
# differential_evolution step 757: f(x)= 18.38592210695763
# differential_evolution step 758: f(x)= 18.121523377493855
# differential_evolution step 759: f(x)= 18.121523377493855
# differential_evolution step 760: f(x)= 18.121523377493855
# differential_evolution step 761: f(x)= 18.121523377493855
# differential_evolution step 762: f(x)= 18.121523377493855
# differential_evolution step 763: f(x)= 18.121523377493855
# differential_evolution step 764: f(x)= 18.121523377493855
# differential_evolution step 765: f(x)= 18.121523377493855
# differential_evolution step 766: f(x)= 18.121523377493855
# differential_evolution step 767: f(x)= 18.121523377493855
# differential_evolution step 768: f(x)= 18.121523377493855
# differential_evolution step 769: f(x)= 18.121523377493855
# differential_evolution step 770: f(x)= 18.121523377493855
# differential_evolution step 771: f(x)= 18.121523377493855
# differential_evolution step 772: f(x)= 18.121523377493855
# differential_evolution step 773: f(x)= 18.121523377493855
# differential_evolution step 774: f(x)= 18.121523377493855
# differential_evolution step 775: f(x)= 18.121523377493855
# differential_evolution step 776: f(x)= 18.121523377493855
# differential_evolution step 777: f(x)= 18.121523377493855
# differential_evolution step 778: f(x)= 18.121523377493855
# differential_evolution step 779: f(x)= 18.121523377493855
# differential_evolution step 780: f(x)= 18.121523377493855
# differential_evolution step 781: f(x)= 18.121523377493855
# differential_evolution step 782: f(x)= 18.121523377493855
# differential_evolution step 783: f(x)= 18.121523377493855
# differential_evolution step 784: f(x)= 18.121523377493855
# differential_evolution step 785: f(x)= 18.121523377493855
# differential_evolution step 786: f(x)= 18.121523377493855
# differential_evolution step 787: f(x)= 18.121523377493855
# differential_evolution step 788: f(x)= 18.121523377493855
# differential_evolution step 789: f(x)= 18.121523377493855
# differential_evolution step 790: f(x)= 18.121523377493855
# differential_evolution step 791: f(x)= 18.121523377493855
# differential_evolution step 792: f(x)= 18.121523377493855
# differential_evolution step 793: f(x)= 18.121523377493855
# differential_evolution step 794: f(x)= 18.121523377493855
# differential_evolution step 795: f(x)= 18.121523377493855
# differential_evolution step 796: f(x)= 18.121523377493855
# differential_evolution step 797: f(x)= 18.121523377493855
# differential_evolution step 798: f(x)= 18.121523377493855
# differential_evolution step 799: f(x)= 18.120971566578614
# differential_evolution step 800: f(x)= 18.120971566578614
# differential_evolution step 801: f(x)= 18.120971566578614
# differential_evolution step 802: f(x)= 18.120971566578614
# differential_evolution step 803: f(x)= 18.120971566578614
# differential_evolution step 804: f(x)= 18.120971566578614
# differential_evolution step 805: f(x)= 18.120971566578614
# differential_evolution step 806: f(x)= 18.120971566578614
# differential_evolution step 807: f(x)= 18.120971566578614
# differential_evolution step 808: f(x)= 16.987480118110717
# differential_evolution step 809: f(x)= 16.987480118110717
# differential_evolution step 810: f(x)= 16.987480118110717
# differential_evolution step 811: f(x)= 16.987480118110717
# differential_evolution step 812: f(x)= 16.987480118110717
# differential_evolution step 813: f(x)= 16.987480118110717
# differential_evolution step 814: f(x)= 16.987480118110717
# differential_evolution step 815: f(x)= 16.987480118110717
# differential_evolution step 816: f(x)= 16.987480118110717
# differential_evolution step 817: f(x)= 16.987480118110717
# differential_evolution step 818: f(x)= 16.987480118110717
# differential_evolution step 819: f(x)= 16.987480118110717
# differential_evolution step 820: f(x)= 16.987480118110717
# differential_evolution step 821: f(x)= 16.987480118110717
# differential_evolution step 822: f(x)= 16.987480118110717
# differential_evolution step 823: f(x)= 16.987480118110717
# differential_evolution step 824: f(x)= 16.987480118110717
# differential_evolution step 825: f(x)= 16.987480118110717
# differential_evolution step 826: f(x)= 16.987480118110717
# differential_evolution step 827: f(x)= 16.987480118110717
# differential_evolution step 828: f(x)= 16.987480118110717
# differential_evolution step 829: f(x)= 16.987480118110717
# differential_evolution step 830: f(x)= 16.987480118110717
# differential_evolution step 831: f(x)= 16.987480118110717
# differential_evolution step 832: f(x)= 16.987480118110717
# differential_evolution step 833: f(x)= 16.987480118110717
# differential_evolution step 834: f(x)= 16.987480118110717
# differential_evolution step 835: f(x)= 16.987480118110717
# differential_evolution step 836: f(x)= 16.987480118110717
# differential_evolution step 837: f(x)= 16.987480118110717
# differential_evolution step 838: f(x)= 16.987480118110717
# differential_evolution step 839: f(x)= 16.987480118110717
# differential_evolution step 840: f(x)= 16.987480118110717
# differential_evolution step 841: f(x)= 16.987480118110717
# differential_evolution step 842: f(x)= 16.987480118110717
# differential_evolution step 843: f(x)= 16.987480118110717
# differential_evolution step 844: f(x)= 16.987480118110717
# differential_evolution step 845: f(x)= 16.987480118110717
# differential_evolution step 846: f(x)= 16.987480118110717
# differential_evolution step 847: f(x)= 16.987480118110717
# differential_evolution step 848: f(x)= 16.987480118110717
# differential_evolution step 849: f(x)= 16.987480118110717
# differential_evolution step 850: f(x)= 16.987480118110717
# differential_evolution step 851: f(x)= 16.987480118110717
# differential_evolution step 852: f(x)= 16.987480118110717
# differential_evolution step 853: f(x)= 16.987480118110717
# differential_evolution step 854: f(x)= 16.987480118110717
# differential_evolution step 855: f(x)= 16.987480118110717
# differential_evolution step 856: f(x)= 16.987480118110717
# differential_evolution step 857: f(x)= 16.987480118110717
# differential_evolution step 858: f(x)= 16.987480118110717
# differential_evolution step 859: f(x)= 16.987480118110717
# differential_evolution step 860: f(x)= 16.987480118110717
# differential_evolution step 861: f(x)= 16.987480118110717
# differential_evolution step 862: f(x)= 16.987480118110717
# differential_evolution step 863: f(x)= 16.987480118110717
# differential_evolution step 864: f(x)= 16.987480118110717
# differential_evolution step 865: f(x)= 16.987480118110717
# differential_evolution step 866: f(x)= 16.987480118110717
# differential_evolution step 867: f(x)= 16.987480118110717
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 9
#       6     return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])
#       8 # Global fit:
# ----> 9 result = differential_evolution(
#      10     objective,
#      11     bounds = bounds,
#      12     strategy='best1bin',
#      13     maxiter=1000,
#      14     popsize=20,
#      15     tol=1e-6,
#      16     disp=True,
#      17     polish=True
#      18 )
#      20 best_params = result.x
#      22 print("Optimize parameters with differential_evolution:")
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_util.py:352, in _transition_to_rng.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     345     message = (
#     346         "The NumPy global RNG was seeded by calling "
#     347         f"`np.random.seed`. Beginning in {end_version}, this "
#     348         "function will no longer use the global RNG."
#     349     ) + cmn_msg
#     350     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 352 return fun(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_differentialevolution.py:502, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, rng, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     485 # using a context manager means that any created Pool objects are
#     486 # cleared up.
#     487 with DifferentialEvolutionSolver(func, bounds, args=args,
#     488                                  strategy=strategy,
#     489                                  maxiter=maxiter,
#    (...)
#     500                                  integrality=integrality,
#     501                                  vectorized=vectorized) as solver:
# --> 502     ret = solver.solve()
#     504 return ret
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_differentialevolution.py:1186, in DifferentialEvolutionSolver.solve(self)
#    1183 for nit in range(1, self.maxiter + 1):
#    1184     # evolve the population by a generation
#    1185     try:
# -> 1186         next(self)
#    1187     except StopIteration:
#    1188         warning_flag = True
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_differentialevolution.py:1601, in DifferentialEvolutionSolver.__next__(self)
#    1599     feasible = True
#    1600     cv = np.atleast_2d([0.])
# -> 1601     energy = self.func(parameters)
#    1602     self._nfev += 1
#    1604 # compare trial and population member
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_util.py:568, in _FunctionWrapper.__call__(self, x)
#     567 def __call__(self, x):
# --> 568     return self.f(x, *self.args)
#
# Cell In[64], line 6, in objective(params)
#       5 def objective(params):
# ----> 6     return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])
#
# Cell In[11], line 27, in chi_squared(params, x, y_obs, sigma)
#      26 def chi_squared(params, x, y_obs, sigma):
# ---> 27     y_model = model_convolved(x, sigma, *params)
#      28     return np.sum((y_obs - y_model)**2)
#
# Cell In[11], line 14, in model_convolved(x, sigma, *params)
#      11 def model_convolved(x, sigma, *params):
#      12     x_hr = np.linspace(min(x), max(x), 4000)
#      13     profile = (
# ---> 14         sersic_1d(x_hr, *params[0:4]) +
#      15         sersic_1d(x_hr, *params[4:8]) +
#      16         sersic_1d(x_hr, *params[8:12]) +
#      17         sersic_1d(x_hr, *params[12:16]) +
#      18         sersic_1d(x_hr, *params[16:20]) +
#      19         sersic_1d(x_hr, *params[20:24])
#      20     )
#      21     kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
#      22     conv_profile = convolve(profile, kernel, mode='same')
#
# Cell In[11], line 9, in sersic_1d(x, I_e, r_e, n, x_0)
#       7 r = np.abs(x - x_0)
#       8 b_n = calculate_bn(n)
# ----> 9 return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
#
# KeyboardInterrupt:

# %%
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, radial_profile_error_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.1189, r_e=5.3924, n=1.8443, x_0=15.9877
# Sérsic 2: I_e=9.7569, r_e=1.9534, n=2.3586, x_0=40.9782
# Sérsic 3: I_e=4.3739, r_e=6.7694, n=0.6375, x_0=61.7451
# Sérsic 4: I_e=4.5400, r_e=2.0662, n=0.7169, x_0=65.9671
# Sérsic 5: I_e=0.7445, r_e=49.9993, n=0.4766, x_0=71.4290
# Sérsic 6: I_e=1.7346, r_e=3.4184, n=1.3259, x_0=72.0542
# [ 0.73242796  2.60283514  0.50610085  0.060872    3.50730819  0.37435574
#   0.37179587  0.01482311  2.55012247  1.01421259  0.15468776  3.49545658
#   4.17657462  2.63488956  0.76224688  0.29279592  0.21774009 11.60172474
#   0.24084114  8.90555436  1.41548935  2.56837954  0.63806802  0.210588
#   0.          0.          0.          0.        ]
# 4.770042849137287

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 141115.18473755335
# differential_evolution step 2: f(x)= 141115.18473755335
# differential_evolution step 3: f(x)= 21759.27801885421
# differential_evolution step 4: f(x)= 21759.27801885421
# differential_evolution step 5: f(x)= 21759.27801885421
# differential_evolution step 6: f(x)= 21747.48669150554
# differential_evolution step 7: f(x)= 21747.48669150554
# differential_evolution step 8: f(x)= 21747.48669150554
# differential_evolution step 9: f(x)= 18557.732885892823
# differential_evolution step 10: f(x)= 8116.1643904676985
# differential_evolution step 11: f(x)= 5527.876989925824
# differential_evolution step 12: f(x)= 5527.876989925824
# differential_evolution step 13: f(x)= 5527.876989925824
# differential_evolution step 14: f(x)= 4187.911163401185
# differential_evolution step 15: f(x)= 4187.911163401185
# differential_evolution step 16: f(x)= 4187.911163401185
# differential_evolution step 17: f(x)= 2190.7233246756778
# differential_evolution step 18: f(x)= 2190.7233246756778
# differential_evolution step 19: f(x)= 2190.7233246756778
# differential_evolution step 20: f(x)= 2190.7233246756778
# differential_evolution step 21: f(x)= 2190.7233246756778
# differential_evolution step 22: f(x)= 2190.7233246756778
# differential_evolution step 23: f(x)= 2190.7233246756778
# differential_evolution step 24: f(x)= 2190.7233246756778
# differential_evolution step 25: f(x)= 2190.7233246756778
# differential_evolution step 26: f(x)= 1962.8283902536443
# differential_evolution step 27: f(x)= 1962.8283902536443
# differential_evolution step 28: f(x)= 1962.8283902536443
# differential_evolution step 29: f(x)= 1962.8283902536443
# differential_evolution step 30: f(x)= 1962.8283902536443
# differential_evolution step 31: f(x)= 1962.8283902536443
# differential_evolution step 32: f(x)= 1962.8283902536443
# differential_evolution step 33: f(x)= 1775.537280712563
# differential_evolution step 34: f(x)= 1775.537280712563
# differential_evolution step 35: f(x)= 1775.537280712563
# differential_evolution step 36: f(x)= 1775.537280712563
# differential_evolution step 37: f(x)= 1775.537280712563
# differential_evolution step 38: f(x)= 1303.0557788029807
# differential_evolution step 39: f(x)= 1303.0557788029807
# differential_evolution step 40: f(x)= 1303.0557788029807
# differential_evolution step 41: f(x)= 860.9072297785679
# differential_evolution step 42: f(x)= 860.9072297785679
# differential_evolution step 43: f(x)= 647.2158804046227
# differential_evolution step 44: f(x)= 647.2158804046227
# differential_evolution step 45: f(x)= 647.2158804046227
# differential_evolution step 46: f(x)= 647.2158804046227
# differential_evolution step 47: f(x)= 424.99833711326573
# differential_evolution step 48: f(x)= 424.99833711326573
# differential_evolution step 49: f(x)= 424.99833711326573
# differential_evolution step 50: f(x)= 424.99833711326573
# differential_evolution step 51: f(x)= 424.99833711326573
# differential_evolution step 52: f(x)= 424.99833711326573
# differential_evolution step 53: f(x)= 424.99833711326573
# differential_evolution step 54: f(x)= 424.99833711326573
# differential_evolution step 55: f(x)= 424.99833711326573
# differential_evolution step 56: f(x)= 424.99833711326573
# differential_evolution step 57: f(x)= 424.99833711326573
# differential_evolution step 58: f(x)= 424.99833711326573
# differential_evolution step 59: f(x)= 424.99833711326573
# differential_evolution step 60: f(x)= 424.99833711326573
# differential_evolution step 61: f(x)= 424.99833711326573
# differential_evolution step 62: f(x)= 424.99833711326573
# differential_evolution step 63: f(x)= 424.99833711326573
# differential_evolution step 64: f(x)= 424.99833711326573
# differential_evolution step 65: f(x)= 424.99833711326573
# differential_evolution step 66: f(x)= 424.99833711326573
# differential_evolution step 67: f(x)= 322.3630252409898
# differential_evolution step 68: f(x)= 322.3630252409898
# differential_evolution step 69: f(x)= 322.3630252409898
# differential_evolution step 70: f(x)= 322.3630252409898
# differential_evolution step 71: f(x)= 322.3630252409898
# differential_evolution step 72: f(x)= 237.58994487723558
# differential_evolution step 73: f(x)= 237.58994487723558
# differential_evolution step 74: f(x)= 237.58994487723558
# differential_evolution step 75: f(x)= 237.58994487723558
# differential_evolution step 76: f(x)= 237.58994487723558
# differential_evolution step 77: f(x)= 237.58994487723558
# differential_evolution step 78: f(x)= 237.58994487723558
# differential_evolution step 79: f(x)= 237.58994487723558
# differential_evolution step 80: f(x)= 237.58994487723558
# differential_evolution step 81: f(x)= 237.58994487723558
# differential_evolution step 82: f(x)= 237.58994487723558
# differential_evolution step 83: f(x)= 237.58994487723558
# differential_evolution step 84: f(x)= 237.58994487723558
# differential_evolution step 85: f(x)= 237.58994487723558
# differential_evolution step 86: f(x)= 237.58994487723558
# differential_evolution step 87: f(x)= 179.4683332311383
# differential_evolution step 88: f(x)= 179.4683332311383
# differential_evolution step 89: f(x)= 179.4683332311383
# differential_evolution step 90: f(x)= 179.4683332311383
# differential_evolution step 91: f(x)= 179.4683332311383
# differential_evolution step 92: f(x)= 179.4683332311383
# differential_evolution step 93: f(x)= 179.4683332311383
# differential_evolution step 94: f(x)= 179.4683332311383
# differential_evolution step 95: f(x)= 179.4683332311383
# differential_evolution step 96: f(x)= 179.4683332311383
# differential_evolution step 97: f(x)= 179.4683332311383
# differential_evolution step 98: f(x)= 179.4683332311383
# differential_evolution step 99: f(x)= 179.4683332311383
# differential_evolution step 100: f(x)= 179.4683332311383
# differential_evolution step 101: f(x)= 179.4683332311383
# differential_evolution step 102: f(x)= 179.4683332311383
# differential_evolution step 103: f(x)= 179.4683332311383
# differential_evolution step 104: f(x)= 179.4683332311383
# differential_evolution step 105: f(x)= 179.4683332311383
# differential_evolution step 106: f(x)= 179.4683332311383
# differential_evolution step 107: f(x)= 179.4683332311383
# differential_evolution step 108: f(x)= 165.59848131996347
# differential_evolution step 109: f(x)= 165.59848131996347
# differential_evolution step 110: f(x)= 165.59848131996347
# differential_evolution step 111: f(x)= 165.59848131996347
# differential_evolution step 112: f(x)= 165.59848131996347
# differential_evolution step 113: f(x)= 165.59848131996347
# differential_evolution step 114: f(x)= 165.59848131996347
# differential_evolution step 115: f(x)= 165.59848131996347
# differential_evolution step 116: f(x)= 148.72361134640693
# differential_evolution step 117: f(x)= 148.72361134640693
# differential_evolution step 118: f(x)= 80.8790864846699
# differential_evolution step 119: f(x)= 80.8790864846699
# differential_evolution step 120: f(x)= 80.8790864846699
# differential_evolution step 121: f(x)= 80.8790864846699
# differential_evolution step 122: f(x)= 80.8790864846699
# differential_evolution step 123: f(x)= 80.8790864846699
# differential_evolution step 124: f(x)= 80.8790864846699
# differential_evolution step 125: f(x)= 80.8790864846699
# differential_evolution step 126: f(x)= 80.8790864846699
# differential_evolution step 127: f(x)= 80.8790864846699
# differential_evolution step 128: f(x)= 80.8790864846699
# differential_evolution step 129: f(x)= 80.8790864846699
# differential_evolution step 130: f(x)= 80.8790864846699
# differential_evolution step 131: f(x)= 80.8790864846699
# differential_evolution step 132: f(x)= 80.8790864846699
# differential_evolution step 133: f(x)= 80.8790864846699
# differential_evolution step 134: f(x)= 80.8790864846699
# differential_evolution step 135: f(x)= 80.8790864846699
# differential_evolution step 136: f(x)= 80.8790864846699
# differential_evolution step 137: f(x)= 80.8790864846699
# differential_evolution step 138: f(x)= 61.491750850385124
# differential_evolution step 139: f(x)= 61.491750850385124
# differential_evolution step 140: f(x)= 61.491750850385124
# differential_evolution step 141: f(x)= 61.491750850385124
# differential_evolution step 142: f(x)= 61.491750850385124
# differential_evolution step 143: f(x)= 61.491750850385124
# differential_evolution step 144: f(x)= 61.491750850385124
# differential_evolution step 145: f(x)= 61.491750850385124
# differential_evolution step 146: f(x)= 61.491750850385124
# differential_evolution step 147: f(x)= 61.491750850385124
# differential_evolution step 148: f(x)= 61.491750850385124
# differential_evolution step 149: f(x)= 61.491750850385124
# differential_evolution step 150: f(x)= 51.532618335867035
# differential_evolution step 151: f(x)= 51.532618335867035
# differential_evolution step 152: f(x)= 51.532618335867035
# differential_evolution step 153: f(x)= 51.532618335867035
# differential_evolution step 154: f(x)= 51.532618335867035
# differential_evolution step 155: f(x)= 51.532618335867035
# differential_evolution step 156: f(x)= 51.532618335867035
# differential_evolution step 157: f(x)= 51.532618335867035
# differential_evolution step 158: f(x)= 51.532618335867035
# differential_evolution step 159: f(x)= 51.532618335867035
# differential_evolution step 160: f(x)= 51.532618335867035
# differential_evolution step 161: f(x)= 51.532618335867035
# differential_evolution step 162: f(x)= 51.532618335867035
# differential_evolution step 163: f(x)= 51.532618335867035
# differential_evolution step 164: f(x)= 51.532618335867035
# differential_evolution step 165: f(x)= 51.532618335867035
# differential_evolution step 166: f(x)= 51.532618335867035
# differential_evolution step 167: f(x)= 51.532618335867035
# differential_evolution step 168: f(x)= 51.532618335867035
# differential_evolution step 169: f(x)= 51.532618335867035
# differential_evolution step 170: f(x)= 51.532618335867035
# differential_evolution step 171: f(x)= 51.532618335867035
# differential_evolution step 172: f(x)= 51.532618335867035
# differential_evolution step 173: f(x)= 51.532618335867035
# differential_evolution step 174: f(x)= 51.532618335867035
# differential_evolution step 175: f(x)= 51.532618335867035
# differential_evolution step 176: f(x)= 51.532618335867035
# differential_evolution step 177: f(x)= 51.532618335867035
# differential_evolution step 178: f(x)= 51.532618335867035
# differential_evolution step 179: f(x)= 51.532618335867035
# differential_evolution step 180: f(x)= 51.532618335867035
# differential_evolution step 181: f(x)= 51.532618335867035
# differential_evolution step 182: f(x)= 51.532618335867035
# differential_evolution step 183: f(x)= 51.532618335867035
# differential_evolution step 184: f(x)= 51.532618335867035
# differential_evolution step 185: f(x)= 51.532618335867035
# differential_evolution step 186: f(x)= 51.532618335867035
# differential_evolution step 187: f(x)= 51.532618335867035
# differential_evolution step 188: f(x)= 51.532618335867035
# differential_evolution step 189: f(x)= 51.532618335867035
# differential_evolution step 190: f(x)= 51.532618335867035
# differential_evolution step 191: f(x)= 51.532618335867035
# differential_evolution step 192: f(x)= 51.532618335867035
# differential_evolution step 193: f(x)= 51.532618335867035
# differential_evolution step 194: f(x)= 51.532618335867035
# differential_evolution step 195: f(x)= 51.2061593878645
# differential_evolution step 196: f(x)= 51.2061593878645
# differential_evolution step 197: f(x)= 51.2061593878645
# differential_evolution step 198: f(x)= 51.2061593878645
# differential_evolution step 199: f(x)= 51.2061593878645
# differential_evolution step 200: f(x)= 51.2061593878645
# differential_evolution step 201: f(x)= 51.2061593878645
# differential_evolution step 202: f(x)= 51.2061593878645
# differential_evolution step 203: f(x)= 51.2061593878645
# differential_evolution step 204: f(x)= 51.2061593878645
# differential_evolution step 205: f(x)= 51.2061593878645
# differential_evolution step 206: f(x)= 46.56596834671594
# differential_evolution step 207: f(x)= 46.56596834671594
# differential_evolution step 208: f(x)= 46.56596834671594
# differential_evolution step 209: f(x)= 46.56596834671594
# differential_evolution step 210: f(x)= 46.56596834671594
# differential_evolution step 211: f(x)= 46.56596834671594
# differential_evolution step 212: f(x)= 46.56596834671594
# differential_evolution step 213: f(x)= 46.56596834671594
# differential_evolution step 214: f(x)= 46.56596834671594
# differential_evolution step 215: f(x)= 46.56596834671594
# differential_evolution step 216: f(x)= 46.56596834671594
# differential_evolution step 217: f(x)= 46.56596834671594
# differential_evolution step 218: f(x)= 46.56596834671594
# differential_evolution step 219: f(x)= 46.56596834671594
# differential_evolution step 220: f(x)= 40.048488271873076
# differential_evolution step 221: f(x)= 39.5561171594077
# differential_evolution step 222: f(x)= 39.5561171594077
# differential_evolution step 223: f(x)= 39.5561171594077
# differential_evolution step 224: f(x)= 39.5561171594077
# differential_evolution step 225: f(x)= 39.5561171594077
# differential_evolution step 226: f(x)= 39.5561171594077
# differential_evolution step 227: f(x)= 39.5561171594077
# differential_evolution step 228: f(x)= 39.5561171594077
# differential_evolution step 229: f(x)= 39.5561171594077
# differential_evolution step 230: f(x)= 39.5561171594077
# differential_evolution step 231: f(x)= 39.5561171594077
# differential_evolution step 232: f(x)= 39.5561171594077
# differential_evolution step 233: f(x)= 39.5561171594077
# differential_evolution step 234: f(x)= 39.5561171594077
# differential_evolution step 235: f(x)= 39.5561171594077
# differential_evolution step 236: f(x)= 39.5561171594077
# differential_evolution step 237: f(x)= 39.5561171594077
# differential_evolution step 238: f(x)= 39.5561171594077
# differential_evolution step 239: f(x)= 39.5561171594077
# differential_evolution step 240: f(x)= 38.88364471130291
# differential_evolution step 241: f(x)= 38.88364471130291
# differential_evolution step 242: f(x)= 38.88364471130291
# differential_evolution step 243: f(x)= 38.88364471130291
# differential_evolution step 244: f(x)= 38.88364471130291
# differential_evolution step 245: f(x)= 38.88364471130291
# differential_evolution step 246: f(x)= 38.88364471130291
# differential_evolution step 247: f(x)= 38.88364471130291
# differential_evolution step 248: f(x)= 38.88364471130291
# differential_evolution step 249: f(x)= 38.88364471130291
# differential_evolution step 250: f(x)= 38.88364471130291
# differential_evolution step 251: f(x)= 38.88364471130291
# differential_evolution step 252: f(x)= 38.88364471130291
# differential_evolution step 253: f(x)= 38.88364471130291
# differential_evolution step 254: f(x)= 38.88364471130291
# differential_evolution step 255: f(x)= 38.88364471130291
# differential_evolution step 256: f(x)= 38.88364471130291
# differential_evolution step 257: f(x)= 38.88364471130291
# differential_evolution step 258: f(x)= 38.88364471130291
# differential_evolution step 259: f(x)= 37.716134026928394
# differential_evolution step 260: f(x)= 37.716134026928394
# differential_evolution step 261: f(x)= 37.716134026928394
# differential_evolution step 262: f(x)= 37.716134026928394
# differential_evolution step 263: f(x)= 37.716134026928394
# differential_evolution step 264: f(x)= 37.716134026928394
# differential_evolution step 265: f(x)= 37.716134026928394
# differential_evolution step 266: f(x)= 37.716134026928394
# differential_evolution step 267: f(x)= 37.716134026928394
# differential_evolution step 268: f(x)= 34.85780049911262
# differential_evolution step 269: f(x)= 34.85780049911262
# differential_evolution step 270: f(x)= 34.85780049911262
# differential_evolution step 271: f(x)= 34.85780049911262
# differential_evolution step 272: f(x)= 34.85780049911262
# differential_evolution step 273: f(x)= 34.85780049911262
# differential_evolution step 274: f(x)= 34.85780049911262
# differential_evolution step 275: f(x)= 34.85780049911262
# differential_evolution step 276: f(x)= 34.85780049911262
# differential_evolution step 277: f(x)= 34.85780049911262
# differential_evolution step 278: f(x)= 34.85780049911262
# differential_evolution step 279: f(x)= 34.85780049911262
# differential_evolution step 280: f(x)= 34.85780049911262
# differential_evolution step 281: f(x)= 34.85780049911262
# differential_evolution step 282: f(x)= 34.85780049911262
# differential_evolution step 283: f(x)= 34.85780049911262
# differential_evolution step 284: f(x)= 34.85780049911262
# differential_evolution step 285: f(x)= 34.85780049911262
# differential_evolution step 286: f(x)= 34.85780049911262
# differential_evolution step 287: f(x)= 34.85780049911262
# differential_evolution step 288: f(x)= 33.0158609553743
# differential_evolution step 289: f(x)= 32.24532249077311
# differential_evolution step 290: f(x)= 32.24532249077311
# differential_evolution step 291: f(x)= 32.24532249077311
# differential_evolution step 292: f(x)= 32.24532249077311
# differential_evolution step 293: f(x)= 32.24532249077311
# differential_evolution step 294: f(x)= 32.24532249077311
# differential_evolution step 295: f(x)= 32.24532249077311
# differential_evolution step 296: f(x)= 32.24532249077311
# differential_evolution step 297: f(x)= 32.24532249077311
# differential_evolution step 298: f(x)= 32.24532249077311
# differential_evolution step 299: f(x)= 32.24532249077311
# differential_evolution step 300: f(x)= 32.24532249077311
# differential_evolution step 301: f(x)= 32.24532249077311
# differential_evolution step 302: f(x)= 29.622826105665233
# differential_evolution step 303: f(x)= 29.622826105665233
# differential_evolution step 304: f(x)= 29.622826105665233
# differential_evolution step 305: f(x)= 29.622826105665233
# differential_evolution step 306: f(x)= 29.622826105665233
# differential_evolution step 307: f(x)= 29.622826105665233
# differential_evolution step 308: f(x)= 29.622826105665233
# differential_evolution step 309: f(x)= 29.622826105665233
# differential_evolution step 310: f(x)= 29.622826105665233
# differential_evolution step 311: f(x)= 29.622826105665233
# differential_evolution step 312: f(x)= 29.622826105665233
# differential_evolution step 313: f(x)= 29.622826105665233
# differential_evolution step 314: f(x)= 29.622826105665233
# differential_evolution step 315: f(x)= 29.622826105665233
# differential_evolution step 316: f(x)= 29.622826105665233
# differential_evolution step 317: f(x)= 29.622826105665233
# differential_evolution step 318: f(x)= 29.622826105665233
# differential_evolution step 319: f(x)= 29.622826105665233
# differential_evolution step 320: f(x)= 29.622826105665233
# differential_evolution step 321: f(x)= 29.622826105665233
# differential_evolution step 322: f(x)= 29.622826105665233
# differential_evolution step 323: f(x)= 29.622826105665233
# differential_evolution step 324: f(x)= 29.622826105665233
# differential_evolution step 325: f(x)= 26.402740161384553
# differential_evolution step 326: f(x)= 26.402740161384553
# differential_evolution step 327: f(x)= 26.402740161384553
# differential_evolution step 328: f(x)= 26.402740161384553
# differential_evolution step 329: f(x)= 26.402740161384553
# differential_evolution step 330: f(x)= 26.402740161384553
# differential_evolution step 331: f(x)= 26.402740161384553
# differential_evolution step 332: f(x)= 26.402740161384553
# differential_evolution step 333: f(x)= 26.402740161384553
# differential_evolution step 334: f(x)= 26.402740161384553
# differential_evolution step 335: f(x)= 25.523203267912947
# differential_evolution step 336: f(x)= 25.523203267912947
# differential_evolution step 337: f(x)= 25.523203267912947
# differential_evolution step 338: f(x)= 25.107632015155165
# differential_evolution step 339: f(x)= 25.107632015155165
# differential_evolution step 340: f(x)= 25.107632015155165
# differential_evolution step 341: f(x)= 22.857821568497776
# differential_evolution step 342: f(x)= 22.857821568497776
# differential_evolution step 343: f(x)= 22.857821568497776
# differential_evolution step 344: f(x)= 22.857821568497776
# differential_evolution step 345: f(x)= 22.857821568497776
# differential_evolution step 346: f(x)= 22.857821568497776
# differential_evolution step 347: f(x)= 22.857821568497776
# differential_evolution step 348: f(x)= 22.857821568497776
# differential_evolution step 349: f(x)= 22.857821568497776
# differential_evolution step 350: f(x)= 22.857821568497776
# differential_evolution step 351: f(x)= 22.857821568497776
# differential_evolution step 352: f(x)= 22.857821568497776
# differential_evolution step 353: f(x)= 22.857821568497776
# differential_evolution step 354: f(x)= 22.857821568497776
# differential_evolution step 355: f(x)= 22.857821568497776
# differential_evolution step 356: f(x)= 22.857821568497776
# differential_evolution step 357: f(x)= 22.857821568497776
# differential_evolution step 358: f(x)= 22.857821568497776
# differential_evolution step 359: f(x)= 22.857821568497776
# differential_evolution step 360: f(x)= 22.857821568497776
# differential_evolution step 361: f(x)= 22.857821568497776
# differential_evolution step 362: f(x)= 22.857821568497776
# differential_evolution step 363: f(x)= 22.857821568497776
# differential_evolution step 364: f(x)= 22.857821568497776
# differential_evolution step 365: f(x)= 22.821588770683185
# differential_evolution step 366: f(x)= 22.821588770683185
# differential_evolution step 367: f(x)= 22.821588770683185
# differential_evolution step 368: f(x)= 22.821588770683185
# differential_evolution step 369: f(x)= 22.821588770683185
# differential_evolution step 370: f(x)= 22.821588770683185
# differential_evolution step 371: f(x)= 22.821588770683185
# differential_evolution step 372: f(x)= 21.89270101136344
# differential_evolution step 373: f(x)= 21.89270101136344
# differential_evolution step 374: f(x)= 21.89270101136344
# differential_evolution step 375: f(x)= 21.89270101136344
# differential_evolution step 376: f(x)= 21.89270101136344
# differential_evolution step 377: f(x)= 21.89270101136344
# differential_evolution step 378: f(x)= 21.89270101136344
# differential_evolution step 379: f(x)= 21.89270101136344
# differential_evolution step 380: f(x)= 21.89270101136344
# differential_evolution step 381: f(x)= 21.75901310146957
# differential_evolution step 382: f(x)= 21.75901310146957
# differential_evolution step 383: f(x)= 21.75901310146957
# differential_evolution step 384: f(x)= 21.75901310146957
# differential_evolution step 385: f(x)= 21.75901310146957
# differential_evolution step 386: f(x)= 21.75901310146957
# differential_evolution step 387: f(x)= 21.75901310146957
# differential_evolution step 388: f(x)= 21.75901310146957
# differential_evolution step 389: f(x)= 21.75901310146957
# differential_evolution step 390: f(x)= 21.75901310146957
# differential_evolution step 391: f(x)= 21.75901310146957
# differential_evolution step 392: f(x)= 21.75901310146957
# differential_evolution step 393: f(x)= 21.75901310146957
# differential_evolution step 394: f(x)= 21.75901310146957
# differential_evolution step 395: f(x)= 21.75901310146957
# differential_evolution step 396: f(x)= 21.75901310146957
# differential_evolution step 397: f(x)= 21.75901310146957
# differential_evolution step 398: f(x)= 21.75901310146957
# differential_evolution step 399: f(x)= 21.75901310146957
# differential_evolution step 400: f(x)= 21.75901310146957
# differential_evolution step 401: f(x)= 21.75901310146957
# differential_evolution step 402: f(x)= 21.75901310146957
# differential_evolution step 403: f(x)= 21.75901310146957
# differential_evolution step 404: f(x)= 21.75901310146957
# differential_evolution step 405: f(x)= 21.75901310146957
# differential_evolution step 406: f(x)= 21.75901310146957
# differential_evolution step 407: f(x)= 21.75901310146957
# differential_evolution step 408: f(x)= 21.75901310146957
# differential_evolution step 409: f(x)= 21.54657726225639
# differential_evolution step 410: f(x)= 21.54657726225639
# differential_evolution step 411: f(x)= 21.54657726225639
# differential_evolution step 412: f(x)= 19.55400761920912
# differential_evolution step 413: f(x)= 19.55400761920912
# differential_evolution step 414: f(x)= 17.97955975321261
# differential_evolution step 415: f(x)= 17.97955975321261
# differential_evolution step 416: f(x)= 17.97955975321261
# differential_evolution step 417: f(x)= 17.97955975321261
# differential_evolution step 418: f(x)= 17.97955975321261
# differential_evolution step 419: f(x)= 17.97955975321261
# differential_evolution step 420: f(x)= 17.97955975321261
# differential_evolution step 421: f(x)= 17.97955975321261
# differential_evolution step 422: f(x)= 17.97955975321261
# differential_evolution step 423: f(x)= 17.97955975321261
# differential_evolution step 424: f(x)= 17.97955975321261
# differential_evolution step 425: f(x)= 17.750756512953913
# differential_evolution step 426: f(x)= 17.750756512953913
# differential_evolution step 427: f(x)= 17.750756512953913
# differential_evolution step 428: f(x)= 17.750756512953913
# differential_evolution step 429: f(x)= 17.750756512953913
# differential_evolution step 430: f(x)= 17.750756512953913
# differential_evolution step 431: f(x)= 17.750756512953913
# differential_evolution step 432: f(x)= 17.750756512953913
# differential_evolution step 433: f(x)= 17.750756512953913
# differential_evolution step 434: f(x)= 17.750756512953913
# differential_evolution step 435: f(x)= 17.750756512953913
# differential_evolution step 436: f(x)= 17.750756512953913
# differential_evolution step 437: f(x)= 17.750756512953913
# differential_evolution step 438: f(x)= 17.750756512953913
# differential_evolution step 439: f(x)= 17.750756512953913
# differential_evolution step 440: f(x)= 17.750756512953913
# differential_evolution step 441: f(x)= 17.750756512953913
# differential_evolution step 442: f(x)= 17.750756512953913
# differential_evolution step 443: f(x)= 17.750756512953913
# differential_evolution step 444: f(x)= 17.750756512953913
# differential_evolution step 445: f(x)= 17.750756512953913
# differential_evolution step 446: f(x)= 17.750756512953913
# differential_evolution step 447: f(x)= 17.750756512953913
# differential_evolution step 448: f(x)= 17.750756512953913
# differential_evolution step 449: f(x)= 17.750756512953913
# differential_evolution step 450: f(x)= 17.750756512953913
# differential_evolution step 451: f(x)= 17.022146973737527
# differential_evolution step 452: f(x)= 17.022146973737527
# differential_evolution step 453: f(x)= 17.022146973737527
# differential_evolution step 454: f(x)= 17.022146973737527
# differential_evolution step 455: f(x)= 17.022146973737527
# differential_evolution step 456: f(x)= 17.022146973737527
# differential_evolution step 457: f(x)= 17.022146973737527
# differential_evolution step 458: f(x)= 17.022146973737527
# differential_evolution step 459: f(x)= 17.022146973737527
# differential_evolution step 460: f(x)= 17.022146973737527
# differential_evolution step 461: f(x)= 17.022146973737527
# differential_evolution step 462: f(x)= 17.022146973737527
# differential_evolution step 463: f(x)= 17.022146973737527
# differential_evolution step 464: f(x)= 17.022146973737527
# differential_evolution step 465: f(x)= 17.022146973737527
# differential_evolution step 466: f(x)= 17.022146973737527
# differential_evolution step 467: f(x)= 17.022146973737527
# differential_evolution step 468: f(x)= 17.022146973737527
# differential_evolution step 469: f(x)= 17.022146973737527
# differential_evolution step 470: f(x)= 17.022146973737527
# differential_evolution step 471: f(x)= 17.022146973737527
# differential_evolution step 472: f(x)= 17.022146973737527
# differential_evolution step 473: f(x)= 17.022146973737527
# differential_evolution step 474: f(x)= 17.022146973737527
# differential_evolution step 475: f(x)= 17.022146973737527
# differential_evolution step 476: f(x)= 17.022146973737527
# differential_evolution step 477: f(x)= 17.022146973737527
# differential_evolution step 478: f(x)= 17.022146973737527
# differential_evolution step 479: f(x)= 17.022146973737527
# differential_evolution step 480: f(x)= 17.022146973737527
# differential_evolution step 481: f(x)= 17.022146973737527
# differential_evolution step 482: f(x)= 17.022146973737527
# differential_evolution step 483: f(x)= 17.022146973737527
# differential_evolution step 484: f(x)= 17.022146973737527
# differential_evolution step 485: f(x)= 17.022146973737527
# differential_evolution step 486: f(x)= 17.022146973737527
# differential_evolution step 487: f(x)= 17.022146973737527
# differential_evolution step 488: f(x)= 17.022146973737527
# differential_evolution step 489: f(x)= 17.022146973737527
# differential_evolution step 490: f(x)= 17.022146973737527
# differential_evolution step 491: f(x)= 17.022146973737527
# differential_evolution step 492: f(x)= 17.022146973737527
# differential_evolution step 493: f(x)= 17.022146973737527
# differential_evolution step 494: f(x)= 17.022146973737527
# differential_evolution step 495: f(x)= 17.022146973737527
# differential_evolution step 496: f(x)= 17.022146973737527
# differential_evolution step 497: f(x)= 17.022146973737527
# differential_evolution step 498: f(x)= 17.022146973737527
# differential_evolution step 499: f(x)= 17.022146973737527
# differential_evolution step 500: f(x)= 17.022146973737527
# differential_evolution step 501: f(x)= 17.022146973737527
# differential_evolution step 502: f(x)= 17.022146973737527
# differential_evolution step 503: f(x)= 17.022146973737527
# differential_evolution step 504: f(x)= 17.022146973737527
# differential_evolution step 505: f(x)= 17.022146973737527
# differential_evolution step 506: f(x)= 17.022146973737527
# differential_evolution step 507: f(x)= 17.022146973737527
# differential_evolution step 508: f(x)= 17.022146973737527
# differential_evolution step 509: f(x)= 16.74962659339406
# differential_evolution step 510: f(x)= 16.74962659339406
# differential_evolution step 511: f(x)= 16.74962659339406
# differential_evolution step 512: f(x)= 16.74962659339406
# differential_evolution step 513: f(x)= 16.74962659339406
# differential_evolution step 514: f(x)= 16.74962659339406
# differential_evolution step 515: f(x)= 16.74962659339406
# differential_evolution step 516: f(x)= 16.57979156919453
# differential_evolution step 517: f(x)= 16.57979156919453
# differential_evolution step 518: f(x)= 16.57979156919453
# differential_evolution step 519: f(x)= 16.57979156919453
# differential_evolution step 520: f(x)= 16.57979156919453
# differential_evolution step 521: f(x)= 16.57979156919453
# differential_evolution step 522: f(x)= 16.57979156919453
# differential_evolution step 523: f(x)= 16.57979156919453
# differential_evolution step 524: f(x)= 16.57979156919453
# differential_evolution step 525: f(x)= 16.57979156919453
# differential_evolution step 526: f(x)= 16.57979156919453
# differential_evolution step 527: f(x)= 16.57979156919453
# differential_evolution step 528: f(x)= 16.57979156919453
# differential_evolution step 529: f(x)= 16.57979156919453
# differential_evolution step 530: f(x)= 16.57979156919453
# differential_evolution step 531: f(x)= 16.57979156919453
# differential_evolution step 532: f(x)= 16.57979156919453
# differential_evolution step 533: f(x)= 16.57979156919453
# differential_evolution step 534: f(x)= 16.57979156919453
# differential_evolution step 535: f(x)= 16.57979156919453
# differential_evolution step 536: f(x)= 16.57979156919453
# differential_evolution step 537: f(x)= 16.57979156919453
# differential_evolution step 538: f(x)= 16.57979156919453
# differential_evolution step 539: f(x)= 16.57979156919453
# differential_evolution step 540: f(x)= 16.57979156919453
# differential_evolution step 541: f(x)= 16.57979156919453
# differential_evolution step 542: f(x)= 16.57979156919453
# differential_evolution step 543: f(x)= 16.57979156919453
# differential_evolution step 544: f(x)= 16.57979156919453
# differential_evolution step 545: f(x)= 16.57979156919453
# differential_evolution step 546: f(x)= 16.57979156919453
# differential_evolution step 547: f(x)= 16.57979156919453
# differential_evolution step 548: f(x)= 16.57979156919453
# differential_evolution step 549: f(x)= 16.57979156919453
# differential_evolution step 550: f(x)= 16.57979156919453
# differential_evolution step 551: f(x)= 15.473673443318107
# differential_evolution step 552: f(x)= 15.473673443318107
# differential_evolution step 553: f(x)= 15.473673443318107
# differential_evolution step 554: f(x)= 15.473673443318107
# differential_evolution step 555: f(x)= 15.473673443318107
# differential_evolution step 556: f(x)= 15.473673443318107
# differential_evolution step 557: f(x)= 15.473673443318107
# differential_evolution step 558: f(x)= 15.473673443318107
# differential_evolution step 559: f(x)= 15.473673443318107
# differential_evolution step 560: f(x)= 15.473673443318107
# differential_evolution step 561: f(x)= 15.473673443318107
# differential_evolution step 562: f(x)= 15.473673443318107
# differential_evolution step 563: f(x)= 13.879029397312593
# differential_evolution step 564: f(x)= 13.879029397312593
# differential_evolution step 565: f(x)= 13.879029397312593
# differential_evolution step 566: f(x)= 13.879029397312593
# differential_evolution step 567: f(x)= 13.879029397312593
# differential_evolution step 568: f(x)= 13.879029397312593
# differential_evolution step 569: f(x)= 13.879029397312593
# differential_evolution step 570: f(x)= 13.879029397312593
# differential_evolution step 571: f(x)= 13.879029397312593
# differential_evolution step 572: f(x)= 13.879029397312593
# differential_evolution step 573: f(x)= 13.879029397312593
# differential_evolution step 574: f(x)= 13.879029397312593
# differential_evolution step 575: f(x)= 13.879029397312593
# differential_evolution step 576: f(x)= 13.879029397312593
# differential_evolution step 577: f(x)= 13.879029397312593
# differential_evolution step 578: f(x)= 13.879029397312593
# differential_evolution step 579: f(x)= 13.879029397312593
# differential_evolution step 580: f(x)= 13.879029397312593
# differential_evolution step 581: f(x)= 13.879029397312593
# differential_evolution step 582: f(x)= 13.879029397312593
# differential_evolution step 583: f(x)= 13.879029397312593
# differential_evolution step 584: f(x)= 13.879029397312593
# differential_evolution step 585: f(x)= 13.879029397312593
# differential_evolution step 586: f(x)= 13.879029397312593
# differential_evolution step 587: f(x)= 13.879029397312593
# differential_evolution step 588: f(x)= 13.879029397312593
# differential_evolution step 589: f(x)= 13.879029397312593
# differential_evolution step 590: f(x)= 13.879029397312593
# differential_evolution step 591: f(x)= 13.879029397312593
# differential_evolution step 592: f(x)= 13.879029397312593
# differential_evolution step 593: f(x)= 13.879029397312593
# differential_evolution step 594: f(x)= 13.879029397312593
# differential_evolution step 595: f(x)= 13.879029397312593
# differential_evolution step 596: f(x)= 13.879029397312593
# differential_evolution step 597: f(x)= 13.879029397312593
# differential_evolution step 598: f(x)= 13.879029397312593
# differential_evolution step 599: f(x)= 13.879029397312593
# differential_evolution step 600: f(x)= 13.879029397312593
# differential_evolution step 601: f(x)= 13.879029397312593
# differential_evolution step 602: f(x)= 13.879029397312593
# differential_evolution step 603: f(x)= 13.879029397312593
# differential_evolution step 604: f(x)= 13.879029397312593
# differential_evolution step 605: f(x)= 13.879029397312593
# differential_evolution step 606: f(x)= 13.879029397312593
# differential_evolution step 607: f(x)= 13.879029397312593
# differential_evolution step 608: f(x)= 13.879029397312593
# differential_evolution step 609: f(x)= 13.879029397312593
# differential_evolution step 610: f(x)= 13.879029397312593
# differential_evolution step 611: f(x)= 13.879029397312593
# differential_evolution step 612: f(x)= 13.879029397312593
# differential_evolution step 613: f(x)= 13.879029397312593
# differential_evolution step 614: f(x)= 13.879029397312593
# differential_evolution step 615: f(x)= 13.879029397312593
# differential_evolution step 616: f(x)= 13.879029397312593
# differential_evolution step 617: f(x)= 13.879029397312593
# differential_evolution step 618: f(x)= 13.879029397312593
# differential_evolution step 619: f(x)= 13.879029397312593
# differential_evolution step 620: f(x)= 13.879029397312593
# differential_evolution step 621: f(x)= 13.879029397312593
# differential_evolution step 622: f(x)= 13.879029397312593
# differential_evolution step 623: f(x)= 13.879029397312593
# differential_evolution step 624: f(x)= 13.879029397312593
# differential_evolution step 625: f(x)= 13.879029397312593
# differential_evolution step 626: f(x)= 13.879029397312593
# differential_evolution step 627: f(x)= 13.879029397312593
# differential_evolution step 628: f(x)= 13.879029397312593
# differential_evolution step 629: f(x)= 13.879029397312593
# differential_evolution step 630: f(x)= 13.879029397312593
# differential_evolution step 631: f(x)= 13.879029397312593
# differential_evolution step 632: f(x)= 13.879029397312593
# differential_evolution step 633: f(x)= 13.879029397312593
# differential_evolution step 634: f(x)= 13.879029397312593
# differential_evolution step 635: f(x)= 13.879029397312593
# differential_evolution step 636: f(x)= 13.879029397312593
# differential_evolution step 637: f(x)= 13.879029397312593
# differential_evolution step 638: f(x)= 13.879029397312593
# differential_evolution step 639: f(x)= 13.879029397312593
# differential_evolution step 640: f(x)= 13.879029397312593
# differential_evolution step 641: f(x)= 13.879029397312593
# differential_evolution step 642: f(x)= 13.879029397312593
# differential_evolution step 643: f(x)= 13.879029397312593
# differential_evolution step 644: f(x)= 13.879029397312593
# differential_evolution step 645: f(x)= 13.879029397312593
# differential_evolution step 646: f(x)= 13.879029397312593
# differential_evolution step 647: f(x)= 13.879029397312593
# differential_evolution step 648: f(x)= 13.879029397312593
# differential_evolution step 649: f(x)= 13.879029397312593
# differential_evolution step 650: f(x)= 13.879029397312593
# differential_evolution step 651: f(x)= 13.879029397312593
# differential_evolution step 652: f(x)= 13.879029397312593
# differential_evolution step 653: f(x)= 13.879029397312593
# differential_evolution step 654: f(x)= 13.879029397312593
# differential_evolution step 655: f(x)= 13.452882162362085
# differential_evolution step 656: f(x)= 13.452882162362085
# differential_evolution step 657: f(x)= 13.452882162362085
# differential_evolution step 658: f(x)= 13.452882162362085
# differential_evolution step 659: f(x)= 13.452882162362085
# differential_evolution step 660: f(x)= 13.452882162362085
# differential_evolution step 661: f(x)= 13.452882162362085
# differential_evolution step 662: f(x)= 13.452882162362085
# differential_evolution step 663: f(x)= 13.452882162362085
# differential_evolution step 664: f(x)= 13.452882162362085
# differential_evolution step 665: f(x)= 13.452882162362085
# differential_evolution step 666: f(x)= 13.452882162362085
# differential_evolution step 667: f(x)= 13.452882162362085
# differential_evolution step 668: f(x)= 13.452882162362085
# differential_evolution step 669: f(x)= 13.452882162362085
# differential_evolution step 670: f(x)= 13.452882162362085
# differential_evolution step 671: f(x)= 13.452882162362085
# differential_evolution step 672: f(x)= 13.452882162362085
# differential_evolution step 673: f(x)= 13.452882162362085
# differential_evolution step 674: f(x)= 13.452882162362085
# differential_evolution step 675: f(x)= 13.452882162362085
# differential_evolution step 676: f(x)= 13.452882162362085
# differential_evolution step 677: f(x)= 13.452882162362085
# differential_evolution step 678: f(x)= 13.452882162362085
# differential_evolution step 679: f(x)= 13.452882162362085
# differential_evolution step 680: f(x)= 13.452882162362085
# differential_evolution step 681: f(x)= 13.452882162362085
# differential_evolution step 682: f(x)= 13.452882162362085
# differential_evolution step 683: f(x)= 13.452882162362085
# differential_evolution step 684: f(x)= 13.452882162362085
# differential_evolution step 685: f(x)= 13.452882162362085
# differential_evolution step 686: f(x)= 13.452882162362085
# differential_evolution step 687: f(x)= 13.452882162362085
# differential_evolution step 688: f(x)= 13.452882162362085
# differential_evolution step 689: f(x)= 13.452882162362085
# differential_evolution step 690: f(x)= 13.452882162362085
# differential_evolution step 691: f(x)= 13.452882162362085
# differential_evolution step 692: f(x)= 13.452882162362085
# differential_evolution step 693: f(x)= 13.452882162362085
# differential_evolution step 694: f(x)= 13.452882162362085
# differential_evolution step 695: f(x)= 13.452882162362085
# differential_evolution step 696: f(x)= 13.452882162362085
# differential_evolution step 697: f(x)= 13.452882162362085
# differential_evolution step 698: f(x)= 13.452882162362085
# differential_evolution step 699: f(x)= 13.452882162362085
# differential_evolution step 700: f(x)= 13.452882162362085
# differential_evolution step 701: f(x)= 13.452882162362085
# differential_evolution step 702: f(x)= 13.452882162362085
# differential_evolution step 703: f(x)= 13.452882162362085
# differential_evolution step 704: f(x)= 13.452882162362085
# differential_evolution step 705: f(x)= 13.452882162362085
# differential_evolution step 706: f(x)= 13.452882162362085
# differential_evolution step 707: f(x)= 13.452882162362085
# differential_evolution step 708: f(x)= 13.452882162362085
# differential_evolution step 709: f(x)= 13.452882162362085
# differential_evolution step 710: f(x)= 13.452882162362085
# differential_evolution step 711: f(x)= 13.452882162362085
# differential_evolution step 712: f(x)= 13.452882162362085
# differential_evolution step 713: f(x)= 13.452882162362085
# differential_evolution step 714: f(x)= 13.452882162362085
# differential_evolution step 715: f(x)= 13.452882162362085
# differential_evolution step 716: f(x)= 13.452882162362085
# differential_evolution step 717: f(x)= 13.452882162362085
# differential_evolution step 718: f(x)= 13.452882162362085
# differential_evolution step 719: f(x)= 13.452882162362085
# differential_evolution step 720: f(x)= 13.452882162362085
# differential_evolution step 721: f(x)= 13.452882162362085
# differential_evolution step 722: f(x)= 13.452882162362085
# differential_evolution step 723: f(x)= 13.452882162362085
# differential_evolution step 724: f(x)= 13.452882162362085
# differential_evolution step 725: f(x)= 13.452882162362085
# differential_evolution step 726: f(x)= 13.452882162362085
# differential_evolution step 727: f(x)= 13.452882162362085
# differential_evolution step 728: f(x)= 13.452882162362085
# differential_evolution step 729: f(x)= 13.452882162362085
# differential_evolution step 730: f(x)= 13.452882162362085
# differential_evolution step 731: f(x)= 13.452882162362085
# differential_evolution step 732: f(x)= 13.452882162362085
# differential_evolution step 733: f(x)= 13.452882162362085
# differential_evolution step 734: f(x)= 13.452882162362085
# differential_evolution step 735: f(x)= 13.452882162362085
# differential_evolution step 736: f(x)= 13.452882162362085
# differential_evolution step 737: f(x)= 13.452882162362085
# differential_evolution step 738: f(x)= 13.452882162362085
# differential_evolution step 739: f(x)= 13.452882162362085
# differential_evolution step 740: f(x)= 13.452882162362085
# differential_evolution step 741: f(x)= 13.452882162362085
# differential_evolution step 742: f(x)= 13.452882162362085
# differential_evolution step 743: f(x)= 13.452882162362085
# differential_evolution step 744: f(x)= 13.452882162362085
# differential_evolution step 745: f(x)= 13.452882162362085
# differential_evolution step 746: f(x)= 13.452882162362085
# differential_evolution step 747: f(x)= 13.452882162362085
# differential_evolution step 748: f(x)= 13.309305309530698
# differential_evolution step 749: f(x)= 13.309305309530698
# differential_evolution step 750: f(x)= 13.309305309530698
# differential_evolution step 751: f(x)= 13.309305309530698
# differential_evolution step 752: f(x)= 13.309305309530698
# differential_evolution step 753: f(x)= 13.309305309530698
# differential_evolution step 754: f(x)= 13.309305309530698
# differential_evolution step 755: f(x)= 13.309305309530698
# differential_evolution step 756: f(x)= 13.309305309530698
# differential_evolution step 757: f(x)= 13.309305309530698
# differential_evolution step 758: f(x)= 13.309305309530698
# differential_evolution step 759: f(x)= 13.309305309530698
# differential_evolution step 760: f(x)= 13.309305309530698
# differential_evolution step 761: f(x)= 13.309305309530698
# differential_evolution step 762: f(x)= 12.96414290429444
# differential_evolution step 763: f(x)= 12.96414290429444
# differential_evolution step 764: f(x)= 12.96414290429444
# differential_evolution step 765: f(x)= 12.96414290429444
# differential_evolution step 766: f(x)= 12.952946479297045
# differential_evolution step 767: f(x)= 12.952946479297045
# differential_evolution step 768: f(x)= 12.952946479297045
# differential_evolution step 769: f(x)= 12.952946479297045
# differential_evolution step 770: f(x)= 12.952946479297045
# differential_evolution step 771: f(x)= 12.952946479297045
# differential_evolution step 772: f(x)= 12.952946479297045
# differential_evolution step 773: f(x)= 12.952946479297045
# differential_evolution step 774: f(x)= 12.895289297222035
# differential_evolution step 775: f(x)= 12.895289297222035
# differential_evolution step 776: f(x)= 12.895289297222035
# differential_evolution step 777: f(x)= 12.895289297222035
# differential_evolution step 778: f(x)= 12.895289297222035
# differential_evolution step 779: f(x)= 12.895289297222035
# differential_evolution step 780: f(x)= 12.895289297222035
# differential_evolution step 781: f(x)= 12.895289297222035
# differential_evolution step 782: f(x)= 12.895289297222035
# differential_evolution step 783: f(x)= 12.895289297222035
# differential_evolution step 784: f(x)= 12.690926238663863
# differential_evolution step 785: f(x)= 12.690926238663863
# differential_evolution step 786: f(x)= 12.690926238663863
# differential_evolution step 787: f(x)= 12.690926238663863
# differential_evolution step 788: f(x)= 12.690926238663863
# differential_evolution step 789: f(x)= 12.373396216656891
# differential_evolution step 790: f(x)= 12.373396216656891
# differential_evolution step 791: f(x)= 12.373396216656891
# differential_evolution step 792: f(x)= 12.373396216656891
# differential_evolution step 793: f(x)= 12.373396216656891
# differential_evolution step 794: f(x)= 12.373396216656891
# differential_evolution step 795: f(x)= 12.373396216656891
# differential_evolution step 796: f(x)= 12.373396216656891
# differential_evolution step 797: f(x)= 12.373396216656891
# differential_evolution step 798: f(x)= 12.373396216656891
# differential_evolution step 799: f(x)= 12.373396216656891
# differential_evolution step 800: f(x)= 12.373396216656891
# differential_evolution step 801: f(x)= 12.373396216656891
# differential_evolution step 802: f(x)= 11.95685077198265
# differential_evolution step 803: f(x)= 11.95685077198265
# differential_evolution step 804: f(x)= 11.95685077198265
# differential_evolution step 805: f(x)= 11.95685077198265
# differential_evolution step 806: f(x)= 11.95685077198265
# differential_evolution step 807: f(x)= 11.95685077198265
# differential_evolution step 808: f(x)= 11.95685077198265
# differential_evolution step 809: f(x)= 11.95685077198265
# differential_evolution step 810: f(x)= 11.95685077198265
# differential_evolution step 811: f(x)= 11.95685077198265
# differential_evolution step 812: f(x)= 11.95685077198265
# differential_evolution step 813: f(x)= 11.95685077198265
# differential_evolution step 814: f(x)= 11.95685077198265
# differential_evolution step 815: f(x)= 11.95685077198265
# differential_evolution step 816: f(x)= 11.95685077198265
# differential_evolution step 817: f(x)= 11.95685077198265
# differential_evolution step 818: f(x)= 11.95685077198265
# differential_evolution step 819: f(x)= 11.95685077198265
# differential_evolution step 820: f(x)= 11.95685077198265
# differential_evolution step 821: f(x)= 11.95685077198265
# differential_evolution step 822: f(x)= 11.95685077198265
# differential_evolution step 823: f(x)= 11.95685077198265
# differential_evolution step 824: f(x)= 11.95685077198265
# differential_evolution step 825: f(x)= 11.95685077198265
# differential_evolution step 826: f(x)= 11.937602182691052
# differential_evolution step 827: f(x)= 11.937602182691052
# differential_evolution step 828: f(x)= 11.937602182691052
# differential_evolution step 829: f(x)= 11.937602182691052
# differential_evolution step 830: f(x)= 11.937602182691052
# differential_evolution step 831: f(x)= 11.937602182691052
# differential_evolution step 832: f(x)= 11.937602182691052
# differential_evolution step 833: f(x)= 11.937602182691052
# differential_evolution step 834: f(x)= 11.937602182691052
# differential_evolution step 835: f(x)= 11.937602182691052
# differential_evolution step 836: f(x)= 11.937602182691052
# differential_evolution step 837: f(x)= 11.937602182691052
# differential_evolution step 838: f(x)= 11.937602182691052
# differential_evolution step 839: f(x)= 11.937602182691052
# differential_evolution step 840: f(x)= 11.937602182691052
# differential_evolution step 841: f(x)= 11.937602182691052
# differential_evolution step 842: f(x)= 11.937602182691052
# differential_evolution step 843: f(x)= 11.937602182691052
# differential_evolution step 844: f(x)= 11.937602182691052
# differential_evolution step 845: f(x)= 11.937602182691052
# differential_evolution step 846: f(x)= 11.937602182691052
# differential_evolution step 847: f(x)= 11.937602182691052
# differential_evolution step 848: f(x)= 11.937602182691052
# differential_evolution step 849: f(x)= 11.937602182691052
# differential_evolution step 850: f(x)= 11.937602182691052
# differential_evolution step 851: f(x)= 11.901951554261029
# differential_evolution step 852: f(x)= 11.758128045570503
# differential_evolution step 853: f(x)= 11.758128045570503
# differential_evolution step 854: f(x)= 11.758128045570503
# differential_evolution step 855: f(x)= 11.758128045570503
# differential_evolution step 856: f(x)= 11.758128045570503
# differential_evolution step 857: f(x)= 11.758128045570503
# differential_evolution step 858: f(x)= 11.758128045570503
# differential_evolution step 859: f(x)= 11.758128045570503
# differential_evolution step 860: f(x)= 11.758128045570503
# differential_evolution step 861: f(x)= 11.758128045570503
# differential_evolution step 862: f(x)= 11.758128045570503
# differential_evolution step 863: f(x)= 11.758128045570503
# differential_evolution step 864: f(x)= 11.758128045570503
# differential_evolution step 865: f(x)= 11.758128045570503
# differential_evolution step 866: f(x)= 11.758128045570503
# differential_evolution step 867: f(x)= 11.758128045570503
# differential_evolution step 868: f(x)= 11.758128045570503
# differential_evolution step 869: f(x)= 11.758128045570503
# differential_evolution step 870: f(x)= 11.758128045570503
# differential_evolution step 871: f(x)= 11.758128045570503
# differential_evolution step 872: f(x)= 11.758128045570503
# differential_evolution step 873: f(x)= 11.758128045570503
# differential_evolution step 874: f(x)= 11.758128045570503
# differential_evolution step 875: f(x)= 11.758128045570503
# differential_evolution step 876: f(x)= 11.758128045570503
# differential_evolution step 877: f(x)= 11.758128045570503
# differential_evolution step 878: f(x)= 11.758128045570503
# differential_evolution step 879: f(x)= 11.64876830082412
# differential_evolution step 880: f(x)= 11.64876830082412
# differential_evolution step 881: f(x)= 11.64876830082412
# differential_evolution step 882: f(x)= 11.64876830082412
# differential_evolution step 883: f(x)= 11.64876830082412
# differential_evolution step 884: f(x)= 11.64876830082412
# differential_evolution step 885: f(x)= 11.64876830082412
# differential_evolution step 886: f(x)= 11.64876830082412
# differential_evolution step 887: f(x)= 11.64876830082412
# differential_evolution step 888: f(x)= 11.64876830082412
# differential_evolution step 889: f(x)= 11.64876830082412
# differential_evolution step 890: f(x)= 11.64876830082412
# differential_evolution step 891: f(x)= 11.64876830082412
# differential_evolution step 892: f(x)= 11.64876830082412
# differential_evolution step 893: f(x)= 11.64876830082412
# differential_evolution step 894: f(x)= 11.64876830082412
# differential_evolution step 895: f(x)= 11.64876830082412
# differential_evolution step 896: f(x)= 11.64876830082412
# differential_evolution step 897: f(x)= 11.64876830082412
# differential_evolution step 898: f(x)= 11.605024109151511
# differential_evolution step 899: f(x)= 11.605024109151511
# differential_evolution step 900: f(x)= 11.605024109151511
# differential_evolution step 901: f(x)= 11.605024109151511
# differential_evolution step 902: f(x)= 11.605024109151511
# differential_evolution step 903: f(x)= 11.605024109151511
# differential_evolution step 904: f(x)= 11.605024109151511
# differential_evolution step 905: f(x)= 11.605024109151511
# differential_evolution step 906: f(x)= 11.605024109151511
# differential_evolution step 907: f(x)= 11.605024109151511
# differential_evolution step 908: f(x)= 11.605024109151511
# differential_evolution step 909: f(x)= 11.605024109151511
# differential_evolution step 910: f(x)= 11.605024109151511
# differential_evolution step 911: f(x)= 11.529864459984928
# differential_evolution step 912: f(x)= 11.307535594177063
# differential_evolution step 913: f(x)= 11.307535594177063
# differential_evolution step 914: f(x)= 11.307535594177063
# differential_evolution step 915: f(x)= 11.307535594177063
# differential_evolution step 916: f(x)= 11.307535594177063
# differential_evolution step 917: f(x)= 11.307535594177063
# differential_evolution step 918: f(x)= 11.307535594177063
# differential_evolution step 919: f(x)= 11.307535594177063
# differential_evolution step 920: f(x)= 11.307535594177063
# differential_evolution step 921: f(x)= 11.307535594177063
# differential_evolution step 922: f(x)= 11.307535594177063
# differential_evolution step 923: f(x)= 11.307535594177063
# differential_evolution step 924: f(x)= 11.307535594177063
# differential_evolution step 925: f(x)= 11.307535594177063
# differential_evolution step 926: f(x)= 11.23819668980693
# differential_evolution step 927: f(x)= 11.23819668980693
# differential_evolution step 928: f(x)= 11.23819668980693
# differential_evolution step 929: f(x)= 11.23819668980693
# differential_evolution step 930: f(x)= 11.23819668980693
# differential_evolution step 931: f(x)= 11.23819668980693
# differential_evolution step 932: f(x)= 11.23819668980693
# differential_evolution step 933: f(x)= 11.23819668980693
# differential_evolution step 934: f(x)= 11.23819668980693
# differential_evolution step 935: f(x)= 11.23819668980693
# differential_evolution step 936: f(x)= 11.23819668980693
# differential_evolution step 937: f(x)= 11.23819668980693
# differential_evolution step 938: f(x)= 11.23819668980693
# differential_evolution step 939: f(x)= 11.23819668980693
# differential_evolution step 940: f(x)= 11.23819668980693
# differential_evolution step 941: f(x)= 11.23819668980693
# differential_evolution step 942: f(x)= 11.23819668980693
# differential_evolution step 943: f(x)= 11.23819668980693
# differential_evolution step 944: f(x)= 11.23819668980693
# differential_evolution step 945: f(x)= 11.23819668980693
# differential_evolution step 946: f(x)= 11.23819668980693
# differential_evolution step 947: f(x)= 11.23819668980693
# differential_evolution step 948: f(x)= 11.23819668980693
# differential_evolution step 949: f(x)= 11.23819668980693
# differential_evolution step 950: f(x)= 11.23819668980693
# differential_evolution step 951: f(x)= 11.23819668980693
# differential_evolution step 952: f(x)= 11.23819668980693
# differential_evolution step 953: f(x)= 11.23819668980693
# differential_evolution step 954: f(x)= 11.23819668980693
# differential_evolution step 955: f(x)= 11.23819668980693
# differential_evolution step 956: f(x)= 11.198802811938215
# differential_evolution step 957: f(x)= 11.198802811938215
# differential_evolution step 958: f(x)= 11.198802811938215
# differential_evolution step 959: f(x)= 11.198802811938215
# differential_evolution step 960: f(x)= 11.198802811938215
# differential_evolution step 961: f(x)= 11.198802811938215
# differential_evolution step 962: f(x)= 11.198802811938215
# differential_evolution step 963: f(x)= 11.198802811938215
# differential_evolution step 964: f(x)= 11.198802811938215
# differential_evolution step 965: f(x)= 11.198802811938215
# differential_evolution step 966: f(x)= 11.198802811938215
# differential_evolution step 967: f(x)= 11.198802811938215
# differential_evolution step 968: f(x)= 11.198802811938215
# differential_evolution step 969: f(x)= 11.198802811938215
# differential_evolution step 970: f(x)= 11.198802811938215
# differential_evolution step 971: f(x)= 11.198802811938215
# differential_evolution step 972: f(x)= 11.198802811938215
# differential_evolution step 973: f(x)= 11.198802811938215
# differential_evolution step 974: f(x)= 11.198802811938215
# differential_evolution step 975: f(x)= 11.16573625595018
# differential_evolution step 976: f(x)= 11.149206400530586
# differential_evolution step 977: f(x)= 11.149206400530586
# differential_evolution step 978: f(x)= 11.149206400530586
# differential_evolution step 979: f(x)= 11.149206400530586
# differential_evolution step 980: f(x)= 11.149206400530586
# differential_evolution step 981: f(x)= 11.149206400530586
# differential_evolution step 982: f(x)= 11.149206400530586
# differential_evolution step 983: f(x)= 11.149206400530586
# differential_evolution step 984: f(x)= 11.149206400530586
# differential_evolution step 985: f(x)= 11.149206400530586
# differential_evolution step 986: f(x)= 11.149206400530586
# differential_evolution step 987: f(x)= 11.149206400530586
# differential_evolution step 988: f(x)= 11.149206400530586
# differential_evolution step 989: f(x)= 11.149206400530586
# differential_evolution step 990: f(x)= 11.149206400530586
# differential_evolution step 991: f(x)= 11.149206400530586
# differential_evolution step 992: f(x)= 11.149206400530586
# differential_evolution step 993: f(x)= 11.149206400530586
# differential_evolution step 994: f(x)= 11.149206400530586
# differential_evolution step 995: f(x)= 11.149206400530586
# differential_evolution step 996: f(x)= 11.149206400530586
# differential_evolution step 997: f(x)= 11.149206400530586
# differential_evolution step 998: f(x)= 11.149206400530586
# differential_evolution step 999: f(x)= 11.149206400530586
# differential_evolution step 1000: f(x)= 11.149206400530586
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17704\68776662.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.8462, r_e=5.1719, n=1.7561, x_0=16.7110
# Sérsic 2: I_e=6.1138, r_e=2.3238, n=2.4959, x_0=41.6043
# Sérsic 3: I_e=5.2313, r_e=5.6425, n=0.4943, x_0=61.7278
# Sérsic 4: I_e=1.7669, r_e=12.0295, n=1.6620, x_0=66.3206
# Sérsic 5: I_e=0.8427, r_e=49.7320, n=0.2102, x_0=72.8258
# Sérsic 6: I_e=3.4808, r_e=2.6768, n=1.1062, x_0=72.4418
# Chi quadro minimo: 11.149206400530586
# False

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[58], line 3
#       1 lower_bounds, upper_bounds = zip(*bounds)
#       2 bounds_list = (list(lower_bounds), list(upper_bounds))
# ----> 3 params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII,
#       4                                              p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)
#       6 print("Optimize parameters with curve fit:")
#       7 chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII, sigmas[2],
#       8     x_axes, n_component, line_name="NII", output_prefix="fit")
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_minpack_py.py:1036, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1032 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#    1033                     **kwargs)
#    1035 if not res.success:
# -> 1036     raise RuntimeError("Optimal parameters not found: " + res.message)
#    1038 infodict = dict(nfev=res.nfev, fvec=res.fun)
#    1039 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, radial_profile_error_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = radial_profile_error_OIII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, radial_profile_error_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[5], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2, radial_profile_error_continuum_2,
                                                                          sigmas[5], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          radial_profile_error_continuum_3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
