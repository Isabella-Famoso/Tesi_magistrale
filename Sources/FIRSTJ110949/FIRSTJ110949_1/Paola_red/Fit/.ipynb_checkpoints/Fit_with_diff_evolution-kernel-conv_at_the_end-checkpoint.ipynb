# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA (ampiezza dell'intervallo sulle x è +- la metà del seeing) e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/Paola_red/FIRST-J110949.3+124614_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/Paola_red/FIRST-J110949.3+124614_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     336   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        22   (2094, 964)   float32

# %%
image_cut = image[49:149, 0:1890]
image_error_cut = image_error[49:149, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.04263
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/PSF/Real_seeing_FIRST_1.txt")
sigmas = seeing / 2.35
print(sigmas)
# Out:
# [1.00391516 1.0803587  1.00353273 1.00194585 1.0715137 ]

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[49:149, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/FIRST-J110949.3+124614_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     363   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        44   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 25)*(y < 35)
mask_wv = wv > 4400
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/Paola_red/Propag_errors/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n_component = 6

def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])+
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'dodgerblue', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 83)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'dodgerblue', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 83)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 81377.16509929097
# differential_evolution step 2: f(x)= 27592.38552360224
# differential_evolution step 3: f(x)= 27485.06159249782
# differential_evolution step 4: f(x)= 27485.06159249782
# differential_evolution step 5: f(x)= 23836.381199212316
# differential_evolution step 6: f(x)= 17380.38083589968
# differential_evolution step 7: f(x)= 17380.38083589968
# differential_evolution step 8: f(x)= 14947.297287488997
# differential_evolution step 9: f(x)= 14947.297287488997
# differential_evolution step 10: f(x)= 14947.297287488997
# differential_evolution step 11: f(x)= 14947.297287488997
# differential_evolution step 12: f(x)= 14507.994039118797
# differential_evolution step 13: f(x)= 14507.994039118797
# differential_evolution step 14: f(x)= 14507.994039118797
# differential_evolution step 15: f(x)= 14507.994039118797
# differential_evolution step 16: f(x)= 14507.994039118797
# differential_evolution step 17: f(x)= 14507.994039118797
# differential_evolution step 18: f(x)= 13790.313154867446
# differential_evolution step 19: f(x)= 13790.313154867446
# differential_evolution step 20: f(x)= 13790.313154867446
# differential_evolution step 21: f(x)= 10402.366200549766
# differential_evolution step 22: f(x)= 10402.366200549766
# differential_evolution step 23: f(x)= 10402.366200549766
# differential_evolution step 24: f(x)= 10402.366200549766
# differential_evolution step 25: f(x)= 10402.366200549766
# differential_evolution step 26: f(x)= 10402.366200549766
# differential_evolution step 27: f(x)= 10402.366200549766
# differential_evolution step 28: f(x)= 10402.366200549766
# differential_evolution step 29: f(x)= 10402.366200549766
# differential_evolution step 30: f(x)= 10402.366200549766
# differential_evolution step 31: f(x)= 10402.366200549766
# differential_evolution step 32: f(x)= 10402.366200549766
# differential_evolution step 33: f(x)= 10402.366200549766
# differential_evolution step 34: f(x)= 10402.366200549766
# differential_evolution step 35: f(x)= 10402.366200549766
# differential_evolution step 36: f(x)= 10402.366200549766
# differential_evolution step 37: f(x)= 10402.366200549766
# differential_evolution step 38: f(x)= 10402.366200549766
# differential_evolution step 39: f(x)= 10402.366200549766
# differential_evolution step 40: f(x)= 10402.366200549766
# differential_evolution step 41: f(x)= 10402.366200549766
# differential_evolution step 42: f(x)= 10402.366200549766
# differential_evolution step 43: f(x)= 10402.366200549766
# differential_evolution step 44: f(x)= 10402.366200549766
# differential_evolution step 45: f(x)= 10402.366200549766
# differential_evolution step 46: f(x)= 8436.483652013949
# differential_evolution step 47: f(x)= 8436.483652013949
# differential_evolution step 48: f(x)= 8436.483652013949
# differential_evolution step 49: f(x)= 8436.483652013949
# differential_evolution step 50: f(x)= 8436.483652013949
# differential_evolution step 51: f(x)= 8436.483652013949
# differential_evolution step 52: f(x)= 8436.483652013949
# differential_evolution step 53: f(x)= 8436.483652013949
# differential_evolution step 54: f(x)= 8436.483652013949
# differential_evolution step 55: f(x)= 8436.483652013949
# differential_evolution step 56: f(x)= 5697.188104443137
# differential_evolution step 57: f(x)= 5697.188104443137
# differential_evolution step 58: f(x)= 5697.188104443137
# differential_evolution step 59: f(x)= 5697.188104443137
# differential_evolution step 60: f(x)= 5697.188104443137
# differential_evolution step 61: f(x)= 5697.188104443137
# differential_evolution step 62: f(x)= 5697.188104443137
# differential_evolution step 63: f(x)= 5697.188104443137
# differential_evolution step 64: f(x)= 5697.188104443137
# differential_evolution step 65: f(x)= 5697.188104443137
# differential_evolution step 66: f(x)= 5697.188104443137
# differential_evolution step 67: f(x)= 5697.188104443137
# differential_evolution step 68: f(x)= 5550.969867628594
# differential_evolution step 69: f(x)= 5550.969867628594
# differential_evolution step 70: f(x)= 5550.969867628594
# differential_evolution step 71: f(x)= 5550.969867628594
# differential_evolution step 72: f(x)= 5550.969867628594
# differential_evolution step 73: f(x)= 5550.969867628594
# differential_evolution step 74: f(x)= 5550.969867628594
# differential_evolution step 75: f(x)= 5550.969867628594
# differential_evolution step 76: f(x)= 5550.969867628594
# differential_evolution step 77: f(x)= 5550.969867628594
# differential_evolution step 78: f(x)= 4776.939994643337
# differential_evolution step 79: f(x)= 4776.939994643337
# differential_evolution step 80: f(x)= 4776.939994643337
# differential_evolution step 81: f(x)= 4776.939994643337
# differential_evolution step 82: f(x)= 4776.939994643337
# differential_evolution step 83: f(x)= 4776.939994643337
# differential_evolution step 84: f(x)= 4776.939994643337
# differential_evolution step 85: f(x)= 4776.939994643337
# differential_evolution step 86: f(x)= 4776.939994643337
# differential_evolution step 87: f(x)= 4776.939994643337
# differential_evolution step 88: f(x)= 4776.939994643337
# differential_evolution step 89: f(x)= 4776.939994643337
# differential_evolution step 90: f(x)= 4776.939994643337
# differential_evolution step 91: f(x)= 4776.939994643337
# differential_evolution step 92: f(x)= 4776.939994643337
# differential_evolution step 93: f(x)= 4355.894827112957
# differential_evolution step 94: f(x)= 4355.894827112957
# differential_evolution step 95: f(x)= 4355.894827112957
# differential_evolution step 96: f(x)= 4355.894827112957
# differential_evolution step 97: f(x)= 4207.223776897755
# differential_evolution step 98: f(x)= 4207.223776897755
# differential_evolution step 99: f(x)= 4207.223776897755
# differential_evolution step 100: f(x)= 4207.223776897755
# differential_evolution step 101: f(x)= 4207.223776897755
# differential_evolution step 102: f(x)= 3507.925701831706
# differential_evolution step 103: f(x)= 3507.925701831706
# differential_evolution step 104: f(x)= 3507.925701831706
# differential_evolution step 105: f(x)= 3507.925701831706
# differential_evolution step 106: f(x)= 3507.925701831706
# differential_evolution step 107: f(x)= 3507.925701831706
# differential_evolution step 108: f(x)= 3507.925701831706
# differential_evolution step 109: f(x)= 3507.925701831706
# differential_evolution step 110: f(x)= 2082.488795709673
# differential_evolution step 111: f(x)= 2082.488795709673
# differential_evolution step 112: f(x)= 2082.488795709673
# differential_evolution step 113: f(x)= 2082.488795709673
# differential_evolution step 114: f(x)= 2082.488795709673
# differential_evolution step 115: f(x)= 2082.488795709673
# differential_evolution step 116: f(x)= 2082.488795709673
# differential_evolution step 117: f(x)= 2082.488795709673
# differential_evolution step 118: f(x)= 2082.488795709673
# differential_evolution step 119: f(x)= 2082.488795709673
# differential_evolution step 120: f(x)= 2082.488795709673
# differential_evolution step 121: f(x)= 2082.488795709673
# differential_evolution step 122: f(x)= 2082.488795709673
# differential_evolution step 123: f(x)= 2082.488795709673
# differential_evolution step 124: f(x)= 2082.488795709673
# differential_evolution step 125: f(x)= 2082.488795709673
# differential_evolution step 126: f(x)= 2082.488795709673
# differential_evolution step 127: f(x)= 2082.488795709673
# differential_evolution step 128: f(x)= 2082.488795709673
# differential_evolution step 129: f(x)= 2082.488795709673
# differential_evolution step 130: f(x)= 2082.488795709673
# differential_evolution step 131: f(x)= 2082.488795709673
# differential_evolution step 132: f(x)= 2082.488795709673
# differential_evolution step 133: f(x)= 2082.488795709673
# differential_evolution step 134: f(x)= 2082.488795709673
# differential_evolution step 135: f(x)= 2082.488795709673
# differential_evolution step 136: f(x)= 2082.488795709673
# differential_evolution step 137: f(x)= 2082.488795709673
# differential_evolution step 138: f(x)= 2082.488795709673
# differential_evolution step 139: f(x)= 2082.488795709673
# differential_evolution step 140: f(x)= 2082.488795709673
# differential_evolution step 141: f(x)= 2082.488795709673
# differential_evolution step 142: f(x)= 2082.488795709673
# differential_evolution step 143: f(x)= 2082.488795709673
# differential_evolution step 144: f(x)= 2082.488795709673
# differential_evolution step 145: f(x)= 2082.488795709673
# differential_evolution step 146: f(x)= 2082.488795709673
# differential_evolution step 147: f(x)= 2082.488795709673
# differential_evolution step 148: f(x)= 2082.488795709673
# differential_evolution step 149: f(x)= 2082.488795709673
# differential_evolution step 150: f(x)= 2082.488795709673
# differential_evolution step 151: f(x)= 2082.488795709673
# differential_evolution step 152: f(x)= 2082.488795709673
# differential_evolution step 153: f(x)= 2082.488795709673
# differential_evolution step 154: f(x)= 2082.488795709673
# differential_evolution step 155: f(x)= 2082.488795709673
# differential_evolution step 156: f(x)= 2082.488795709673
# differential_evolution step 157: f(x)= 2082.488795709673
# differential_evolution step 158: f(x)= 2082.488795709673
# differential_evolution step 159: f(x)= 2082.488795709673
# differential_evolution step 160: f(x)= 2082.488795709673
# differential_evolution step 161: f(x)= 2082.488795709673
# differential_evolution step 162: f(x)= 2082.488795709673
# differential_evolution step 163: f(x)= 2082.488795709673
# differential_evolution step 164: f(x)= 2082.488795709673
# differential_evolution step 165: f(x)= 2082.488795709673
# differential_evolution step 166: f(x)= 2082.488795709673
# differential_evolution step 167: f(x)= 2082.488795709673
# differential_evolution step 168: f(x)= 2082.488795709673
# differential_evolution step 169: f(x)= 2082.488795709673
# differential_evolution step 170: f(x)= 2082.488795709673
# differential_evolution step 171: f(x)= 2082.488795709673
# differential_evolution step 172: f(x)= 2082.488795709673
# differential_evolution step 173: f(x)= 2082.488795709673
# differential_evolution step 174: f(x)= 2082.488795709673
# differential_evolution step 175: f(x)= 2082.488795709673
# differential_evolution step 176: f(x)= 2082.488795709673
# differential_evolution step 177: f(x)= 2082.488795709673
# differential_evolution step 178: f(x)= 2082.488795709673
# differential_evolution step 179: f(x)= 2082.488795709673
# differential_evolution step 180: f(x)= 2082.488795709673
# differential_evolution step 181: f(x)= 2082.488795709673
# differential_evolution step 182: f(x)= 2082.488795709673
# differential_evolution step 183: f(x)= 2082.488795709673
# differential_evolution step 184: f(x)= 2082.488795709673
# differential_evolution step 185: f(x)= 2082.488795709673
# differential_evolution step 186: f(x)= 2082.488795709673
# differential_evolution step 187: f(x)= 2082.488795709673
# differential_evolution step 188: f(x)= 2082.488795709673
# differential_evolution step 189: f(x)= 2082.488795709673
# differential_evolution step 190: f(x)= 2082.488795709673
# differential_evolution step 191: f(x)= 2082.488795709673
# differential_evolution step 192: f(x)= 2082.488795709673
# differential_evolution step 193: f(x)= 2020.1944544239338
# differential_evolution step 194: f(x)= 2020.1944544239338
# differential_evolution step 195: f(x)= 2020.1944544239338
# differential_evolution step 196: f(x)= 2020.1944544239338
# differential_evolution step 197: f(x)= 2020.1944544239338
# differential_evolution step 198: f(x)= 2020.1944544239338
# differential_evolution step 199: f(x)= 2020.1944544239338
# differential_evolution step 200: f(x)= 2020.1944544239338
# differential_evolution step 201: f(x)= 2020.1944544239338
# differential_evolution step 202: f(x)= 2020.1944544239338
# differential_evolution step 203: f(x)= 2020.1944544239338
# differential_evolution step 204: f(x)= 2020.1944544239338
# differential_evolution step 205: f(x)= 2020.1944544239338
# differential_evolution step 206: f(x)= 2020.1944544239338
# differential_evolution step 207: f(x)= 2020.1944544239338
# differential_evolution step 208: f(x)= 2020.1944544239338
# differential_evolution step 209: f(x)= 2020.1944544239338
# differential_evolution step 210: f(x)= 2020.1944544239338
# differential_evolution step 211: f(x)= 2020.1944544239338
# differential_evolution step 212: f(x)= 2020.1944544239338
# differential_evolution step 213: f(x)= 2020.1944544239338
# differential_evolution step 214: f(x)= 2020.1944544239338
# differential_evolution step 215: f(x)= 2020.1944544239338
# differential_evolution step 216: f(x)= 2020.1944544239338
# differential_evolution step 217: f(x)= 2020.1944544239338
# differential_evolution step 218: f(x)= 2020.1944544239338
# differential_evolution step 219: f(x)= 2020.1944544239338
# differential_evolution step 220: f(x)= 2020.1944544239338
# differential_evolution step 221: f(x)= 2020.1944544239338
# differential_evolution step 222: f(x)= 2020.1944544239338
# differential_evolution step 223: f(x)= 2020.1944544239338
# differential_evolution step 224: f(x)= 2020.1944544239338
# differential_evolution step 225: f(x)= 2020.1944544239338
# differential_evolution step 226: f(x)= 2020.1944544239338
# differential_evolution step 227: f(x)= 2020.1944544239338
# differential_evolution step 228: f(x)= 2020.1944544239338
# differential_evolution step 229: f(x)= 2020.1944544239338
# differential_evolution step 230: f(x)= 2020.1944544239338
# differential_evolution step 231: f(x)= 2020.1944544239338
# differential_evolution step 232: f(x)= 2020.1944544239338
# differential_evolution step 233: f(x)= 2020.1944544239338
# differential_evolution step 234: f(x)= 2020.1944544239338
# differential_evolution step 235: f(x)= 2020.1944544239338
# differential_evolution step 236: f(x)= 2020.1944544239338
# differential_evolution step 237: f(x)= 2020.1944544239338
# differential_evolution step 238: f(x)= 2020.1944544239338
# differential_evolution step 239: f(x)= 2020.1944544239338
# differential_evolution step 240: f(x)= 2020.1944544239338
# differential_evolution step 241: f(x)= 2020.1944544239338
# differential_evolution step 242: f(x)= 2020.1944544239338
# differential_evolution step 243: f(x)= 1666.8787229933466
# differential_evolution step 244: f(x)= 1666.8787229933466
# differential_evolution step 245: f(x)= 1666.8787229933466
# differential_evolution step 246: f(x)= 1666.8787229933466
# differential_evolution step 247: f(x)= 1666.8787229933466
# differential_evolution step 248: f(x)= 1666.8787229933466
# differential_evolution step 249: f(x)= 1666.8787229933466
# differential_evolution step 250: f(x)= 1666.8787229933466
# differential_evolution step 251: f(x)= 1666.8787229933466
# differential_evolution step 252: f(x)= 1666.8787229933466
# differential_evolution step 253: f(x)= 1666.8787229933466
# differential_evolution step 254: f(x)= 1666.8787229933466
# differential_evolution step 255: f(x)= 1666.8787229933466
# differential_evolution step 256: f(x)= 1666.8787229933466
# differential_evolution step 257: f(x)= 1666.8787229933466
# differential_evolution step 258: f(x)= 1666.8787229933466
# differential_evolution step 259: f(x)= 1666.8787229933466
# differential_evolution step 260: f(x)= 1666.8787229933466
# differential_evolution step 261: f(x)= 1666.8787229933466
# differential_evolution step 262: f(x)= 1666.8787229933466
# differential_evolution step 263: f(x)= 1666.8787229933466
# differential_evolution step 264: f(x)= 1666.8787229933466
# differential_evolution step 265: f(x)= 1666.8787229933466
# differential_evolution step 266: f(x)= 1666.8787229933466
# differential_evolution step 267: f(x)= 1666.8787229933466
# differential_evolution step 268: f(x)= 1666.8787229933466
# differential_evolution step 269: f(x)= 1666.8787229933466
# differential_evolution step 270: f(x)= 1666.8787229933466
# differential_evolution step 271: f(x)= 1666.8787229933466
# differential_evolution step 272: f(x)= 1666.8787229933466
# differential_evolution step 273: f(x)= 1666.8787229933466
# differential_evolution step 274: f(x)= 1666.8787229933466
# differential_evolution step 275: f(x)= 1666.8787229933466
# differential_evolution step 276: f(x)= 1666.8787229933466
# differential_evolution step 277: f(x)= 1666.8787229933466
# differential_evolution step 278: f(x)= 1666.8787229933466
# differential_evolution step 279: f(x)= 1666.8787229933466
# differential_evolution step 280: f(x)= 1666.8787229933466
# differential_evolution step 281: f(x)= 1666.8787229933466
# differential_evolution step 282: f(x)= 1666.8787229933466
# differential_evolution step 283: f(x)= 1666.8787229933466
# differential_evolution step 284: f(x)= 1666.8787229933466
# differential_evolution step 285: f(x)= 1666.8787229933466
# differential_evolution step 286: f(x)= 1666.8787229933466
# differential_evolution step 287: f(x)= 1666.8787229933466
# differential_evolution step 288: f(x)= 1666.8787229933466
# differential_evolution step 289: f(x)= 1666.8787229933466
# differential_evolution step 290: f(x)= 1666.8787229933466
# differential_evolution step 291: f(x)= 1666.8787229933466
# differential_evolution step 292: f(x)= 1666.8787229933466
# differential_evolution step 293: f(x)= 1666.8787229933466
# differential_evolution step 294: f(x)= 1666.8787229933466
# differential_evolution step 295: f(x)= 1666.8787229933466
# differential_evolution step 296: f(x)= 1666.8787229933466
# differential_evolution step 297: f(x)= 1666.8787229933466
# differential_evolution step 298: f(x)= 1666.8787229933466
# differential_evolution step 299: f(x)= 1666.8787229933466
# differential_evolution step 300: f(x)= 1136.511247858848
# differential_evolution step 301: f(x)= 1136.511247858848
# differential_evolution step 302: f(x)= 1136.511247858848
# differential_evolution step 303: f(x)= 1136.511247858848
# differential_evolution step 304: f(x)= 1136.511247858848
# differential_evolution step 305: f(x)= 1136.511247858848
# differential_evolution step 306: f(x)= 1136.511247858848
# differential_evolution step 307: f(x)= 1136.511247858848
# differential_evolution step 308: f(x)= 1136.511247858848
# differential_evolution step 309: f(x)= 1136.511247858848
# differential_evolution step 310: f(x)= 1136.511247858848
# differential_evolution step 311: f(x)= 1136.511247858848
# differential_evolution step 312: f(x)= 1136.511247858848
# differential_evolution step 313: f(x)= 1136.511247858848
# differential_evolution step 314: f(x)= 1136.511247858848
# differential_evolution step 315: f(x)= 1136.511247858848
# differential_evolution step 316: f(x)= 1136.511247858848
# differential_evolution step 317: f(x)= 1136.511247858848
# differential_evolution step 318: f(x)= 1136.511247858848
# differential_evolution step 319: f(x)= 1136.511247858848
# differential_evolution step 320: f(x)= 1136.511247858848
# differential_evolution step 321: f(x)= 1136.511247858848
# differential_evolution step 322: f(x)= 1136.511247858848
# differential_evolution step 323: f(x)= 1136.511247858848
# differential_evolution step 324: f(x)= 1136.511247858848
# differential_evolution step 325: f(x)= 1136.511247858848
# differential_evolution step 326: f(x)= 1136.511247858848
# differential_evolution step 327: f(x)= 1136.511247858848
# differential_evolution step 328: f(x)= 1136.511247858848
# differential_evolution step 329: f(x)= 1136.511247858848
# differential_evolution step 330: f(x)= 1136.511247858848
# differential_evolution step 331: f(x)= 1136.511247858848
# differential_evolution step 332: f(x)= 1136.511247858848
# differential_evolution step 333: f(x)= 1136.511247858848
# differential_evolution step 334: f(x)= 1136.511247858848
# differential_evolution step 335: f(x)= 1136.511247858848
# differential_evolution step 336: f(x)= 1136.511247858848
# differential_evolution step 337: f(x)= 1136.511247858848
# differential_evolution step 338: f(x)= 1136.511247858848
# differential_evolution step 339: f(x)= 1136.511247858848
# differential_evolution step 340: f(x)= 1136.511247858848
# differential_evolution step 341: f(x)= 1136.511247858848
# differential_evolution step 342: f(x)= 1136.511247858848
# differential_evolution step 343: f(x)= 1115.323693469848
# differential_evolution step 344: f(x)= 1115.323693469848
# differential_evolution step 345: f(x)= 1115.323693469848
# differential_evolution step 346: f(x)= 1115.323693469848
# differential_evolution step 347: f(x)= 1115.323693469848
# differential_evolution step 348: f(x)= 1115.323693469848
# differential_evolution step 349: f(x)= 1115.323693469848
# differential_evolution step 350: f(x)= 1115.323693469848
# differential_evolution step 351: f(x)= 1115.323693469848
# differential_evolution step 352: f(x)= 1099.1741440321714
# differential_evolution step 353: f(x)= 1099.1741440321714
# differential_evolution step 354: f(x)= 1099.1741440321714
# differential_evolution step 355: f(x)= 1099.1741440321714
# differential_evolution step 356: f(x)= 1099.1741440321714
# differential_evolution step 357: f(x)= 1099.1741440321714
# differential_evolution step 358: f(x)= 1099.1741440321714
# differential_evolution step 359: f(x)= 1099.1741440321714
# differential_evolution step 360: f(x)= 1099.1741440321714
# differential_evolution step 361: f(x)= 1064.7560614010165
# differential_evolution step 362: f(x)= 1064.7560614010165
# differential_evolution step 363: f(x)= 1064.7560614010165
# differential_evolution step 364: f(x)= 1064.7560614010165
# differential_evolution step 365: f(x)= 1064.7560614010165
# differential_evolution step 366: f(x)= 1064.7560614010165
# differential_evolution step 367: f(x)= 1064.7560614010165
# differential_evolution step 368: f(x)= 1064.7560614010165
# differential_evolution step 369: f(x)= 1064.7560614010165
# differential_evolution step 370: f(x)= 1064.7560614010165
# differential_evolution step 371: f(x)= 1064.7560614010165
# differential_evolution step 372: f(x)= 1064.7560614010165
# differential_evolution step 373: f(x)= 1064.7560614010165
# differential_evolution step 374: f(x)= 1064.7560614010165
# differential_evolution step 375: f(x)= 1064.7560614010165
# differential_evolution step 376: f(x)= 1064.7560614010165
# differential_evolution step 377: f(x)= 1025.2555174715624
# differential_evolution step 378: f(x)= 1025.2555174715624
# differential_evolution step 379: f(x)= 1025.2555174715624
# differential_evolution step 380: f(x)= 1025.2555174715624
# differential_evolution step 381: f(x)= 1025.2555174715624
# differential_evolution step 382: f(x)= 1025.2555174715624
# differential_evolution step 383: f(x)= 1025.2555174715624
# differential_evolution step 384: f(x)= 1025.2555174715624
# differential_evolution step 385: f(x)= 1025.2555174715624
# differential_evolution step 386: f(x)= 1025.2555174715624
# differential_evolution step 387: f(x)= 1025.2555174715624
# differential_evolution step 388: f(x)= 1025.2555174715624
# differential_evolution step 389: f(x)= 1025.2555174715624
# differential_evolution step 390: f(x)= 1025.2555174715624
# differential_evolution step 391: f(x)= 1025.2555174715624
# differential_evolution step 392: f(x)= 1025.2555174715624
# differential_evolution step 393: f(x)= 1025.2555174715624
# differential_evolution step 394: f(x)= 677.4603153019871
# differential_evolution step 395: f(x)= 677.4603153019871
# differential_evolution step 396: f(x)= 677.4603153019871
# differential_evolution step 397: f(x)= 677.4603153019871
# differential_evolution step 398: f(x)= 677.4603153019871
# differential_evolution step 399: f(x)= 677.4603153019871
# differential_evolution step 400: f(x)= 677.4603153019871
# differential_evolution step 401: f(x)= 677.4603153019871
# differential_evolution step 402: f(x)= 677.4603153019871
# differential_evolution step 403: f(x)= 677.4603153019871
# differential_evolution step 404: f(x)= 677.4603153019871
# differential_evolution step 405: f(x)= 677.4603153019871
# differential_evolution step 406: f(x)= 677.4603153019871
# differential_evolution step 407: f(x)= 677.4603153019871
# differential_evolution step 408: f(x)= 677.4603153019871
# differential_evolution step 409: f(x)= 677.4603153019871
# differential_evolution step 410: f(x)= 677.4603153019871
# differential_evolution step 411: f(x)= 677.4603153019871
# differential_evolution step 412: f(x)= 677.4603153019871
# differential_evolution step 413: f(x)= 677.4603153019871
# differential_evolution step 414: f(x)= 677.4603153019871
# differential_evolution step 415: f(x)= 677.4603153019871
# differential_evolution step 416: f(x)= 677.4603153019871
# differential_evolution step 417: f(x)= 677.4603153019871
# differential_evolution step 418: f(x)= 677.4603153019871
# differential_evolution step 419: f(x)= 677.4603153019871
# differential_evolution step 420: f(x)= 677.4603153019871
# differential_evolution step 421: f(x)= 677.4603153019871
# differential_evolution step 422: f(x)= 677.4603153019871
# differential_evolution step 423: f(x)= 677.4603153019871
# differential_evolution step 424: f(x)= 677.4603153019871
# differential_evolution step 425: f(x)= 677.4603153019871
# differential_evolution step 426: f(x)= 677.4603153019871
# differential_evolution step 427: f(x)= 656.5107668003288
# differential_evolution step 428: f(x)= 656.5107668003288
# differential_evolution step 429: f(x)= 656.5107668003288
# differential_evolution step 430: f(x)= 656.5107668003288
# differential_evolution step 431: f(x)= 656.5107668003288
# differential_evolution step 432: f(x)= 656.5107668003288
# differential_evolution step 433: f(x)= 656.5107668003288
# differential_evolution step 434: f(x)= 656.5107668003288
# differential_evolution step 435: f(x)= 656.5107668003288
# differential_evolution step 436: f(x)= 656.5107668003288
# differential_evolution step 437: f(x)= 656.5107668003288
# differential_evolution step 438: f(x)= 656.5107668003288
# differential_evolution step 439: f(x)= 656.5107668003288
# differential_evolution step 440: f(x)= 656.5107668003288
# differential_evolution step 441: f(x)= 656.5107668003288
# differential_evolution step 442: f(x)= 656.5107668003288
# differential_evolution step 443: f(x)= 656.5107668003288
# differential_evolution step 444: f(x)= 656.5107668003288
# differential_evolution step 445: f(x)= 656.5107668003288
# differential_evolution step 446: f(x)= 656.5107668003288
# differential_evolution step 447: f(x)= 656.5107668003288
# differential_evolution step 448: f(x)= 656.5107668003288
# differential_evolution step 449: f(x)= 656.5107668003288
# differential_evolution step 450: f(x)= 656.5107668003288
# differential_evolution step 451: f(x)= 656.5107668003288
# differential_evolution step 452: f(x)= 656.5107668003288
# differential_evolution step 453: f(x)= 656.5107668003288
# differential_evolution step 454: f(x)= 656.5107668003288
# differential_evolution step 455: f(x)= 656.5107668003288
# differential_evolution step 456: f(x)= 656.5107668003288
# differential_evolution step 457: f(x)= 529.8402341966083
# differential_evolution step 458: f(x)= 529.8402341966083
# differential_evolution step 459: f(x)= 529.8402341966083
# differential_evolution step 460: f(x)= 529.8402341966083
# differential_evolution step 461: f(x)= 529.8402341966083
# differential_evolution step 462: f(x)= 529.8402341966083
# differential_evolution step 463: f(x)= 529.8402341966083
# differential_evolution step 464: f(x)= 529.8402341966083
# differential_evolution step 465: f(x)= 529.8402341966083
# differential_evolution step 466: f(x)= 529.8402341966083
# differential_evolution step 467: f(x)= 529.8402341966083
# differential_evolution step 468: f(x)= 529.8402341966083
# differential_evolution step 469: f(x)= 529.8402341966083
# differential_evolution step 470: f(x)= 439.84813841544826
# differential_evolution step 471: f(x)= 439.84813841544826
# differential_evolution step 472: f(x)= 439.84813841544826
# differential_evolution step 473: f(x)= 439.84813841544826
# differential_evolution step 474: f(x)= 439.84813841544826
# differential_evolution step 475: f(x)= 439.84813841544826
# differential_evolution step 476: f(x)= 439.84813841544826
# differential_evolution step 477: f(x)= 439.84813841544826
# differential_evolution step 478: f(x)= 439.84813841544826
# differential_evolution step 479: f(x)= 439.84813841544826
# differential_evolution step 480: f(x)= 439.84813841544826
# differential_evolution step 481: f(x)= 439.84813841544826
# differential_evolution step 482: f(x)= 439.84813841544826
# differential_evolution step 483: f(x)= 439.84813841544826
# differential_evolution step 484: f(x)= 439.84813841544826
# differential_evolution step 485: f(x)= 439.84813841544826
# differential_evolution step 486: f(x)= 439.84813841544826
# differential_evolution step 487: f(x)= 439.84813841544826
# differential_evolution step 488: f(x)= 439.84813841544826
# differential_evolution step 489: f(x)= 439.84813841544826
# differential_evolution step 490: f(x)= 439.84813841544826
# differential_evolution step 491: f(x)= 439.84813841544826
# differential_evolution step 492: f(x)= 439.84813841544826
# differential_evolution step 493: f(x)= 439.84813841544826
# differential_evolution step 494: f(x)= 439.84813841544826
# differential_evolution step 495: f(x)= 439.84813841544826
# differential_evolution step 496: f(x)= 439.84813841544826
# differential_evolution step 497: f(x)= 439.84813841544826
# differential_evolution step 498: f(x)= 428.3874158424047
# differential_evolution step 499: f(x)= 428.3874158424047
# differential_evolution step 500: f(x)= 428.3874158424047
# differential_evolution step 501: f(x)= 428.3874158424047
# differential_evolution step 502: f(x)= 428.3874158424047
# differential_evolution step 503: f(x)= 428.3874158424047
# differential_evolution step 504: f(x)= 428.3874158424047
# differential_evolution step 505: f(x)= 428.3874158424047
# differential_evolution step 506: f(x)= 428.3874158424047
# differential_evolution step 507: f(x)= 428.3874158424047
# differential_evolution step 508: f(x)= 428.3874158424047
# differential_evolution step 509: f(x)= 428.3874158424047
# differential_evolution step 510: f(x)= 409.7255812799563
# differential_evolution step 511: f(x)= 409.7255812799563
# differential_evolution step 512: f(x)= 389.33193800415
# differential_evolution step 513: f(x)= 389.33193800415
# differential_evolution step 514: f(x)= 389.33193800415
# differential_evolution step 515: f(x)= 389.33193800415
# differential_evolution step 516: f(x)= 389.33193800415
# differential_evolution step 517: f(x)= 353.612165983764
# differential_evolution step 518: f(x)= 353.612165983764
# differential_evolution step 519: f(x)= 353.612165983764
# differential_evolution step 520: f(x)= 353.612165983764
# differential_evolution step 521: f(x)= 353.612165983764
# differential_evolution step 522: f(x)= 353.612165983764
# differential_evolution step 523: f(x)= 353.612165983764
# differential_evolution step 524: f(x)= 296.33915393620305
# differential_evolution step 525: f(x)= 296.33915393620305
# differential_evolution step 526: f(x)= 296.33915393620305
# differential_evolution step 527: f(x)= 296.33915393620305
# differential_evolution step 528: f(x)= 296.33915393620305
# differential_evolution step 529: f(x)= 296.33915393620305
# differential_evolution step 530: f(x)= 296.33915393620305
# differential_evolution step 531: f(x)= 296.33915393620305
# differential_evolution step 532: f(x)= 296.33915393620305
# differential_evolution step 533: f(x)= 296.33915393620305
# differential_evolution step 534: f(x)= 296.33915393620305
# differential_evolution step 535: f(x)= 296.33915393620305
# differential_evolution step 536: f(x)= 296.33915393620305
# differential_evolution step 537: f(x)= 296.33915393620305
# differential_evolution step 538: f(x)= 296.33915393620305
# differential_evolution step 539: f(x)= 296.33915393620305
# differential_evolution step 540: f(x)= 296.33915393620305
# differential_evolution step 541: f(x)= 296.33915393620305
# differential_evolution step 542: f(x)= 296.33915393620305
# differential_evolution step 543: f(x)= 296.33915393620305
# differential_evolution step 544: f(x)= 296.33915393620305
# differential_evolution step 545: f(x)= 296.33915393620305
# differential_evolution step 546: f(x)= 296.33915393620305
# differential_evolution step 547: f(x)= 296.33915393620305
# differential_evolution step 548: f(x)= 296.33915393620305
# differential_evolution step 549: f(x)= 296.33915393620305
# differential_evolution step 550: f(x)= 296.33915393620305
# differential_evolution step 551: f(x)= 296.33915393620305
# differential_evolution step 552: f(x)= 284.43433653494105
# differential_evolution step 553: f(x)= 284.43433653494105
# differential_evolution step 554: f(x)= 284.43433653494105
# differential_evolution step 555: f(x)= 284.43433653494105
# differential_evolution step 556: f(x)= 284.43433653494105
# differential_evolution step 557: f(x)= 284.43433653494105
# differential_evolution step 558: f(x)= 284.43433653494105
# differential_evolution step 559: f(x)= 284.43433653494105
# differential_evolution step 560: f(x)= 284.43433653494105
# differential_evolution step 561: f(x)= 284.43433653494105
# differential_evolution step 562: f(x)= 284.43433653494105
# differential_evolution step 563: f(x)= 284.43433653494105
# differential_evolution step 564: f(x)= 284.43433653494105
# differential_evolution step 565: f(x)= 279.21496590688105
# differential_evolution step 566: f(x)= 279.21496590688105
# differential_evolution step 567: f(x)= 279.21496590688105
# differential_evolution step 568: f(x)= 279.21496590688105
# differential_evolution step 569: f(x)= 279.21496590688105
# differential_evolution step 570: f(x)= 279.21496590688105
# differential_evolution step 571: f(x)= 279.21496590688105
# differential_evolution step 572: f(x)= 262.1518126412299
# differential_evolution step 573: f(x)= 262.1518126412299
# differential_evolution step 574: f(x)= 262.1518126412299
# differential_evolution step 575: f(x)= 262.1518126412299
# differential_evolution step 576: f(x)= 262.1518126412299
# differential_evolution step 577: f(x)= 262.1518126412299
# differential_evolution step 578: f(x)= 262.1518126412299
# differential_evolution step 579: f(x)= 262.1518126412299
# differential_evolution step 580: f(x)= 262.1518126412299
# differential_evolution step 581: f(x)= 262.1518126412299
# differential_evolution step 582: f(x)= 262.1518126412299
# differential_evolution step 583: f(x)= 262.1518126412299
# differential_evolution step 584: f(x)= 262.1518126412299
# differential_evolution step 585: f(x)= 262.1518126412299
# differential_evolution step 586: f(x)= 262.1518126412299
# differential_evolution step 587: f(x)= 262.1518126412299
# differential_evolution step 588: f(x)= 262.1518126412299
# differential_evolution step 589: f(x)= 262.1518126412299
# differential_evolution step 590: f(x)= 262.1518126412299
# differential_evolution step 591: f(x)= 262.1518126412299
# differential_evolution step 592: f(x)= 262.1518126412299
# differential_evolution step 593: f(x)= 262.1518126412299
# differential_evolution step 594: f(x)= 262.1518126412299
# differential_evolution step 595: f(x)= 262.1518126412299
# differential_evolution step 596: f(x)= 262.1518126412299
# differential_evolution step 597: f(x)= 262.1518126412299
# differential_evolution step 598: f(x)= 262.1518126412299
# differential_evolution step 599: f(x)= 262.1518126412299
# differential_evolution step 600: f(x)= 262.1518126412299
# differential_evolution step 601: f(x)= 262.1518126412299
# differential_evolution step 602: f(x)= 262.1518126412299
# differential_evolution step 603: f(x)= 262.1518126412299
# differential_evolution step 604: f(x)= 262.1518126412299
# differential_evolution step 605: f(x)= 262.1518126412299
# differential_evolution step 606: f(x)= 262.1518126412299
# differential_evolution step 607: f(x)= 250.7660615251723
# differential_evolution step 608: f(x)= 250.7660615251723
# differential_evolution step 609: f(x)= 250.7660615251723
# differential_evolution step 610: f(x)= 250.7660615251723
# differential_evolution step 611: f(x)= 250.7660615251723
# differential_evolution step 612: f(x)= 250.7660615251723
# differential_evolution step 613: f(x)= 250.7660615251723
# differential_evolution step 614: f(x)= 226.28778536181315
# differential_evolution step 615: f(x)= 226.28778536181315
# differential_evolution step 616: f(x)= 226.28778536181315
# differential_evolution step 617: f(x)= 226.28778536181315
# differential_evolution step 618: f(x)= 226.28778536181315
# differential_evolution step 619: f(x)= 226.28778536181315
# differential_evolution step 620: f(x)= 226.28778536181315
# differential_evolution step 621: f(x)= 226.28778536181315
# differential_evolution step 622: f(x)= 226.28778536181315
# differential_evolution step 623: f(x)= 226.28778536181315
# differential_evolution step 624: f(x)= 226.28778536181315
# differential_evolution step 625: f(x)= 226.28778536181315
# differential_evolution step 626: f(x)= 226.28778536181315
# differential_evolution step 627: f(x)= 226.28778536181315
# differential_evolution step 628: f(x)= 226.28778536181315
# differential_evolution step 629: f(x)= 226.28778536181315
# differential_evolution step 630: f(x)= 226.28778536181315
# differential_evolution step 631: f(x)= 226.28778536181315
# differential_evolution step 632: f(x)= 226.28778536181315
# differential_evolution step 633: f(x)= 226.28778536181315
# differential_evolution step 634: f(x)= 226.28778536181315
# differential_evolution step 635: f(x)= 226.28778536181315
# differential_evolution step 636: f(x)= 226.28778536181315
# differential_evolution step 637: f(x)= 226.28778536181315
# differential_evolution step 638: f(x)= 226.28778536181315
# differential_evolution step 639: f(x)= 226.28778536181315
# differential_evolution step 640: f(x)= 209.45227338636957
# differential_evolution step 641: f(x)= 209.45227338636957
# differential_evolution step 642: f(x)= 209.45227338636957
# differential_evolution step 643: f(x)= 209.45227338636957
# differential_evolution step 644: f(x)= 209.45227338636957
# differential_evolution step 645: f(x)= 209.45227338636957
# differential_evolution step 646: f(x)= 209.45227338636957
# differential_evolution step 647: f(x)= 209.45227338636957
# differential_evolution step 648: f(x)= 209.45227338636957
# differential_evolution step 649: f(x)= 209.45227338636957
# differential_evolution step 650: f(x)= 209.45227338636957
# differential_evolution step 651: f(x)= 209.45227338636957
# differential_evolution step 652: f(x)= 209.45227338636957
# differential_evolution step 653: f(x)= 209.45227338636957
# differential_evolution step 654: f(x)= 209.45227338636957
# differential_evolution step 655: f(x)= 209.45227338636957
# differential_evolution step 656: f(x)= 202.62609516309638
# differential_evolution step 657: f(x)= 202.62609516309638
# differential_evolution step 658: f(x)= 202.62609516309638
# differential_evolution step 659: f(x)= 202.62609516309638
# differential_evolution step 660: f(x)= 202.62609516309638
# differential_evolution step 661: f(x)= 202.62609516309638
# differential_evolution step 662: f(x)= 202.62609516309638
# differential_evolution step 663: f(x)= 202.62609516309638
# differential_evolution step 664: f(x)= 202.62609516309638
# differential_evolution step 665: f(x)= 202.62609516309638
# differential_evolution step 666: f(x)= 199.89310063346088
# differential_evolution step 667: f(x)= 199.89310063346088
# differential_evolution step 668: f(x)= 199.89310063346088
# differential_evolution step 669: f(x)= 199.89310063346088
# differential_evolution step 670: f(x)= 199.89310063346088
# differential_evolution step 671: f(x)= 199.89310063346088
# differential_evolution step 672: f(x)= 199.89310063346088
# differential_evolution step 673: f(x)= 199.89310063346088
# differential_evolution step 674: f(x)= 199.89310063346088
# differential_evolution step 675: f(x)= 199.89310063346088
# differential_evolution step 676: f(x)= 199.89310063346088
# differential_evolution step 677: f(x)= 199.89310063346088
# differential_evolution step 678: f(x)= 199.89310063346088
# differential_evolution step 679: f(x)= 199.89310063346088
# differential_evolution step 680: f(x)= 199.89310063346088
# differential_evolution step 681: f(x)= 199.89310063346088
# differential_evolution step 682: f(x)= 199.89310063346088
# differential_evolution step 683: f(x)= 199.89310063346088
# differential_evolution step 684: f(x)= 199.89310063346088
# differential_evolution step 685: f(x)= 199.89310063346088
# differential_evolution step 686: f(x)= 199.89310063346088
# differential_evolution step 687: f(x)= 199.89310063346088
# differential_evolution step 688: f(x)= 199.89310063346088
# differential_evolution step 689: f(x)= 199.89310063346088
# differential_evolution step 690: f(x)= 199.89310063346088
# differential_evolution step 691: f(x)= 199.89310063346088
# differential_evolution step 692: f(x)= 199.89310063346088
# differential_evolution step 693: f(x)= 199.89310063346088
# differential_evolution step 694: f(x)= 199.89310063346088
# differential_evolution step 695: f(x)= 199.89310063346088
# differential_evolution step 696: f(x)= 199.89310063346088
# differential_evolution step 697: f(x)= 199.89310063346088
# differential_evolution step 698: f(x)= 199.89310063346088
# differential_evolution step 699: f(x)= 199.89310063346088
# differential_evolution step 700: f(x)= 199.89310063346088
# differential_evolution step 701: f(x)= 199.89310063346088
# differential_evolution step 702: f(x)= 188.60323377917845
# differential_evolution step 703: f(x)= 188.60323377917845
# differential_evolution step 704: f(x)= 188.60323377917845
# differential_evolution step 705: f(x)= 188.60323377917845
# differential_evolution step 706: f(x)= 188.60323377917845
# differential_evolution step 707: f(x)= 188.60323377917845
# differential_evolution step 708: f(x)= 188.60323377917845
# differential_evolution step 709: f(x)= 188.60323377917845
# differential_evolution step 710: f(x)= 188.60323377917845
# differential_evolution step 711: f(x)= 188.60323377917845
# differential_evolution step 712: f(x)= 188.60323377917845
# differential_evolution step 713: f(x)= 188.60323377917845
# differential_evolution step 714: f(x)= 188.60323377917845
# differential_evolution step 715: f(x)= 188.60323377917845
# differential_evolution step 716: f(x)= 188.60323377917845
# differential_evolution step 717: f(x)= 188.60323377917845
# differential_evolution step 718: f(x)= 188.60323377917845
# differential_evolution step 719: f(x)= 188.60323377917845
# differential_evolution step 720: f(x)= 188.60323377917845
# differential_evolution step 721: f(x)= 188.60323377917845
# differential_evolution step 722: f(x)= 188.60323377917845
# differential_evolution step 723: f(x)= 187.83421952478545
# differential_evolution step 724: f(x)= 187.83421952478545
# differential_evolution step 725: f(x)= 187.83421952478545
# differential_evolution step 726: f(x)= 187.83421952478545
# differential_evolution step 727: f(x)= 187.83421952478545
# differential_evolution step 728: f(x)= 187.83421952478545
# differential_evolution step 729: f(x)= 187.83421952478545
# differential_evolution step 730: f(x)= 187.83421952478545
# differential_evolution step 731: f(x)= 187.83421952478545
# differential_evolution step 732: f(x)= 187.83421952478545
# differential_evolution step 733: f(x)= 187.83421952478545
# differential_evolution step 734: f(x)= 187.83421952478545
# differential_evolution step 735: f(x)= 185.7865913464766
# differential_evolution step 736: f(x)= 185.7865913464766
# differential_evolution step 737: f(x)= 182.88548414124762
# differential_evolution step 738: f(x)= 182.88548414124762
# differential_evolution step 739: f(x)= 182.88548414124762
# differential_evolution step 740: f(x)= 182.88548414124762
# differential_evolution step 741: f(x)= 182.88548414124762
# differential_evolution step 742: f(x)= 182.88548414124762
# differential_evolution step 743: f(x)= 182.88548414124762
# differential_evolution step 744: f(x)= 179.23762157715015
# differential_evolution step 745: f(x)= 179.23762157715015
# differential_evolution step 746: f(x)= 179.23762157715015
# differential_evolution step 747: f(x)= 179.23762157715015
# differential_evolution step 748: f(x)= 179.23762157715015
# differential_evolution step 749: f(x)= 179.23762157715015
# differential_evolution step 750: f(x)= 179.23762157715015
# differential_evolution step 751: f(x)= 179.23762157715015
# differential_evolution step 752: f(x)= 179.23762157715015
# differential_evolution step 753: f(x)= 179.23762157715015
# differential_evolution step 754: f(x)= 179.23762157715015
# differential_evolution step 755: f(x)= 179.23762157715015
# differential_evolution step 756: f(x)= 179.23762157715015
# differential_evolution step 757: f(x)= 179.23762157715015
# differential_evolution step 758: f(x)= 179.23762157715015
# differential_evolution step 759: f(x)= 179.23762157715015
# differential_evolution step 760: f(x)= 179.23762157715015
# differential_evolution step 761: f(x)= 179.23762157715015
# differential_evolution step 762: f(x)= 179.23762157715015
# differential_evolution step 763: f(x)= 179.23762157715015
# differential_evolution step 764: f(x)= 179.23762157715015
# differential_evolution step 765: f(x)= 179.23762157715015
# differential_evolution step 766: f(x)= 179.23762157715015
# differential_evolution step 767: f(x)= 179.23762157715015
# differential_evolution step 768: f(x)= 167.96478606913823
# differential_evolution step 769: f(x)= 167.96478606913823
# differential_evolution step 770: f(x)= 167.96478606913823
# differential_evolution step 771: f(x)= 167.96478606913823
# differential_evolution step 772: f(x)= 167.96478606913823
# differential_evolution step 773: f(x)= 167.96478606913823
# differential_evolution step 774: f(x)= 167.96478606913823
# differential_evolution step 775: f(x)= 167.96478606913823
# differential_evolution step 776: f(x)= 167.96478606913823
# differential_evolution step 777: f(x)= 167.96478606913823
# differential_evolution step 778: f(x)= 167.96478606913823
# differential_evolution step 779: f(x)= 167.96478606913823
# differential_evolution step 780: f(x)= 167.96478606913823
# differential_evolution step 781: f(x)= 167.96478606913823
# differential_evolution step 782: f(x)= 162.27660548316885
# differential_evolution step 783: f(x)= 162.27660548316885
# differential_evolution step 784: f(x)= 162.27660548316885
# differential_evolution step 785: f(x)= 162.27660548316885
# differential_evolution step 786: f(x)= 162.27660548316885
# differential_evolution step 787: f(x)= 162.27660548316885
# differential_evolution step 788: f(x)= 162.27660548316885
# differential_evolution step 789: f(x)= 162.27660548316885
# differential_evolution step 790: f(x)= 162.27660548316885
# differential_evolution step 791: f(x)= 162.27660548316885
# differential_evolution step 792: f(x)= 162.27660548316885
# differential_evolution step 793: f(x)= 162.27660548316885
# differential_evolution step 794: f(x)= 162.27660548316885
# differential_evolution step 795: f(x)= 162.27660548316885
# differential_evolution step 796: f(x)= 162.27660548316885
# differential_evolution step 797: f(x)= 162.27660548316885
# differential_evolution step 798: f(x)= 162.27660548316885
# differential_evolution step 799: f(x)= 162.27660548316885
# differential_evolution step 800: f(x)= 162.27660548316885
# differential_evolution step 801: f(x)= 162.27660548316885
# differential_evolution step 802: f(x)= 162.27660548316885
# differential_evolution step 803: f(x)= 162.27660548316885
# differential_evolution step 804: f(x)= 162.27660548316885
# differential_evolution step 805: f(x)= 161.35086638334838
# differential_evolution step 806: f(x)= 161.35086638334838
# differential_evolution step 807: f(x)= 161.35086638334838
# differential_evolution step 808: f(x)= 161.35086638334838
# differential_evolution step 809: f(x)= 161.35086638334838
# differential_evolution step 810: f(x)= 161.35086638334838
# differential_evolution step 811: f(x)= 161.35086638334838
# differential_evolution step 812: f(x)= 161.35086638334838
# differential_evolution step 813: f(x)= 161.35086638334838
# differential_evolution step 814: f(x)= 161.35086638334838
# differential_evolution step 815: f(x)= 161.35086638334838
# differential_evolution step 816: f(x)= 161.35086638334838
# differential_evolution step 817: f(x)= 161.35086638334838
# differential_evolution step 818: f(x)= 161.35086638334838
# differential_evolution step 819: f(x)= 161.35086638334838
# differential_evolution step 820: f(x)= 161.35086638334838
# differential_evolution step 821: f(x)= 161.35086638334838
# differential_evolution step 822: f(x)= 161.35086638334838
# differential_evolution step 823: f(x)= 161.35086638334838
# differential_evolution step 824: f(x)= 161.35086638334838
# differential_evolution step 825: f(x)= 161.35086638334838
# differential_evolution step 826: f(x)= 161.35086638334838
# differential_evolution step 827: f(x)= 161.35086638334838
# differential_evolution step 828: f(x)= 161.35086638334838
# differential_evolution step 829: f(x)= 161.35086638334838
# differential_evolution step 830: f(x)= 161.35086638334838
# differential_evolution step 831: f(x)= 161.35086638334838
# differential_evolution step 832: f(x)= 161.35086638334838
# differential_evolution step 833: f(x)= 161.35086638334838
# differential_evolution step 834: f(x)= 161.35086638334838
# differential_evolution step 835: f(x)= 161.35086638334838
# differential_evolution step 836: f(x)= 161.35086638334838
# differential_evolution step 837: f(x)= 161.35086638334838
# differential_evolution step 838: f(x)= 160.53977560353104
# differential_evolution step 839: f(x)= 160.53977560353104
# differential_evolution step 840: f(x)= 160.53977560353104
# differential_evolution step 841: f(x)= 160.53977560353104
# differential_evolution step 842: f(x)= 160.53977560353104
# differential_evolution step 843: f(x)= 160.53977560353104
# differential_evolution step 844: f(x)= 160.53977560353104
# differential_evolution step 845: f(x)= 159.55884386827785
# differential_evolution step 846: f(x)= 159.55884386827785
# differential_evolution step 847: f(x)= 159.55884386827785
# differential_evolution step 848: f(x)= 159.55884386827785
# differential_evolution step 849: f(x)= 159.55884386827785
# differential_evolution step 850: f(x)= 157.09407226867583
# differential_evolution step 851: f(x)= 157.09407226867583
# differential_evolution step 852: f(x)= 157.09407226867583
# differential_evolution step 853: f(x)= 157.09407226867583
# differential_evolution step 854: f(x)= 157.09407226867583
# differential_evolution step 855: f(x)= 157.09407226867583
# differential_evolution step 856: f(x)= 157.09407226867583
# differential_evolution step 857: f(x)= 157.09407226867583
# differential_evolution step 858: f(x)= 149.90470298993074
# differential_evolution step 859: f(x)= 149.90470298993074
# differential_evolution step 860: f(x)= 149.90470298993074
# differential_evolution step 861: f(x)= 149.90470298993074
# differential_evolution step 862: f(x)= 149.90470298993074
# differential_evolution step 863: f(x)= 149.90470298993074
# differential_evolution step 864: f(x)= 149.90470298993074
# differential_evolution step 865: f(x)= 149.90470298993074
# differential_evolution step 866: f(x)= 149.90470298993074
# differential_evolution step 867: f(x)= 149.90470298993074
# differential_evolution step 868: f(x)= 149.90470298993074
# differential_evolution step 869: f(x)= 149.90470298993074
# differential_evolution step 870: f(x)= 149.90470298993074
# differential_evolution step 871: f(x)= 149.90470298993074
# differential_evolution step 872: f(x)= 149.90470298993074
# differential_evolution step 873: f(x)= 149.90470298993074
# differential_evolution step 874: f(x)= 149.90470298993074
# differential_evolution step 875: f(x)= 149.90470298993074
# differential_evolution step 876: f(x)= 149.90470298993074
# differential_evolution step 877: f(x)= 149.90470298993074
# differential_evolution step 878: f(x)= 149.90470298993074
# differential_evolution step 879: f(x)= 149.90470298993074
# differential_evolution step 880: f(x)= 149.90470298993074
# differential_evolution step 881: f(x)= 149.90470298993074
# differential_evolution step 882: f(x)= 149.90470298993074
# differential_evolution step 883: f(x)= 149.90470298993074
# differential_evolution step 884: f(x)= 149.90470298993074
# differential_evolution step 885: f(x)= 149.90470298993074
# differential_evolution step 886: f(x)= 149.90470298993074
# differential_evolution step 887: f(x)= 149.90470298993074
# differential_evolution step 888: f(x)= 147.880433087926
# differential_evolution step 889: f(x)= 147.880433087926
# differential_evolution step 890: f(x)= 147.880433087926
# differential_evolution step 891: f(x)= 147.880433087926
# differential_evolution step 892: f(x)= 147.880433087926
# differential_evolution step 893: f(x)= 147.880433087926
# differential_evolution step 894: f(x)= 147.880433087926
# differential_evolution step 895: f(x)= 147.880433087926
# differential_evolution step 896: f(x)= 147.880433087926
# differential_evolution step 897: f(x)= 147.880433087926
# differential_evolution step 898: f(x)= 147.880433087926
# differential_evolution step 899: f(x)= 147.880433087926
# differential_evolution step 900: f(x)= 147.880433087926
# differential_evolution step 901: f(x)= 147.880433087926
# differential_evolution step 902: f(x)= 147.880433087926
# differential_evolution step 903: f(x)= 147.880433087926
# differential_evolution step 904: f(x)= 147.880433087926
# differential_evolution step 905: f(x)= 147.880433087926
# differential_evolution step 906: f(x)= 147.880433087926
# differential_evolution step 907: f(x)= 147.880433087926
# differential_evolution step 908: f(x)= 147.880433087926
# differential_evolution step 909: f(x)= 147.880433087926
# differential_evolution step 910: f(x)= 147.880433087926
# differential_evolution step 911: f(x)= 147.880433087926
# differential_evolution step 912: f(x)= 147.44043286537527
# differential_evolution step 913: f(x)= 147.44043286537527
# differential_evolution step 914: f(x)= 143.09540870899636
# differential_evolution step 915: f(x)= 143.09540870899636
# differential_evolution step 916: f(x)= 143.09540870899636
# differential_evolution step 917: f(x)= 143.09540870899636
# differential_evolution step 918: f(x)= 143.09540870899636
# differential_evolution step 919: f(x)= 143.09540870899636
# differential_evolution step 920: f(x)= 143.09540870899636
# differential_evolution step 921: f(x)= 143.09540870899636
# differential_evolution step 922: f(x)= 143.09540870899636
# differential_evolution step 923: f(x)= 143.09540870899636
# differential_evolution step 924: f(x)= 143.09540870899636
# differential_evolution step 925: f(x)= 143.09540870899636
# differential_evolution step 926: f(x)= 143.09540870899636
# differential_evolution step 927: f(x)= 143.09540870899636
# differential_evolution step 928: f(x)= 143.09540870899636
# differential_evolution step 929: f(x)= 143.09540870899636
# differential_evolution step 930: f(x)= 143.09540870899636
# differential_evolution step 931: f(x)= 143.09540870899636
# differential_evolution step 932: f(x)= 143.09540870899636
# differential_evolution step 933: f(x)= 143.09540870899636
# differential_evolution step 934: f(x)= 143.09540870899636
# differential_evolution step 935: f(x)= 143.09540870899636
# differential_evolution step 936: f(x)= 143.09540870899636
# differential_evolution step 937: f(x)= 143.09540870899636
# differential_evolution step 938: f(x)= 134.73351739937462
# differential_evolution step 939: f(x)= 134.73351739937462
# differential_evolution step 940: f(x)= 134.73351739937462
# differential_evolution step 941: f(x)= 134.73351739937462
# differential_evolution step 942: f(x)= 134.73351739937462
# differential_evolution step 943: f(x)= 134.73351739937462
# differential_evolution step 944: f(x)= 134.73351739937462
# differential_evolution step 945: f(x)= 134.73351739937462
# differential_evolution step 946: f(x)= 134.73351739937462
# differential_evolution step 947: f(x)= 134.73351739937462
# differential_evolution step 948: f(x)= 134.73351739937462
# differential_evolution step 949: f(x)= 134.73351739937462
# differential_evolution step 950: f(x)= 134.73351739937462
# differential_evolution step 951: f(x)= 134.73351739937462
# differential_evolution step 952: f(x)= 134.73351739937462
# differential_evolution step 953: f(x)= 134.73351739937462
# differential_evolution step 954: f(x)= 134.73351739937462
# differential_evolution step 955: f(x)= 134.73351739937462
# differential_evolution step 956: f(x)= 134.73351739937462
# differential_evolution step 957: f(x)= 134.73351739937462
# differential_evolution step 958: f(x)= 134.73351739937462
# differential_evolution step 959: f(x)= 134.73351739937462
# differential_evolution step 960: f(x)= 134.73351739937462
# differential_evolution step 961: f(x)= 134.73351739937462
# differential_evolution step 962: f(x)= 134.73351739937462
# differential_evolution step 963: f(x)= 134.73351739937462
# differential_evolution step 964: f(x)= 134.73351739937462
# differential_evolution step 965: f(x)= 134.73351739937462
# differential_evolution step 966: f(x)= 134.73351739937462
# differential_evolution step 967: f(x)= 134.73351739937462
# differential_evolution step 968: f(x)= 134.73351739937462
# differential_evolution step 969: f(x)= 134.73351739937462
# differential_evolution step 970: f(x)= 134.73351739937462
# differential_evolution step 971: f(x)= 134.73351739937462
# differential_evolution step 972: f(x)= 134.73351739937462
# differential_evolution step 973: f(x)= 134.73351739937462
# differential_evolution step 974: f(x)= 134.73351739937462
# differential_evolution step 975: f(x)= 134.73351739937462
# differential_evolution step 976: f(x)= 134.73351739937462
# differential_evolution step 977: f(x)= 134.73351739937462
# differential_evolution step 978: f(x)= 134.73351739937462
# differential_evolution step 979: f(x)= 134.73351739937462
# differential_evolution step 980: f(x)= 134.73351739937462
# differential_evolution step 981: f(x)= 134.73351739937462
# differential_evolution step 982: f(x)= 134.73351739937462
# differential_evolution step 983: f(x)= 134.73351739937462
# differential_evolution step 984: f(x)= 134.73351739937462
# differential_evolution step 985: f(x)= 134.73351739937462
# differential_evolution step 986: f(x)= 134.73351739937462
# differential_evolution step 987: f(x)= 134.73351739937462
# differential_evolution step 988: f(x)= 134.73351739937462
# differential_evolution step 989: f(x)= 134.73351739937462
# differential_evolution step 990: f(x)= 134.73351739937462
# differential_evolution step 991: f(x)= 134.73351739937462
# differential_evolution step 992: f(x)= 134.73351739937462
# differential_evolution step 993: f(x)= 134.73351739937462
# differential_evolution step 994: f(x)= 134.73351739937462
# differential_evolution step 995: f(x)= 134.73351739937462
# differential_evolution step 996: f(x)= 134.73351739937462
# differential_evolution step 997: f(x)= 132.3961249312852
# differential_evolution step 998: f(x)= 132.3961249312852
# differential_evolution step 999: f(x)= 132.3961249312852
# differential_evolution step 1000: f(x)= 132.3961249312852
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5400\3111683727.py:11: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.1936, r_e=8.1370, n=2.3920, x_0=16.7786
# Sérsic 2: I_e=2.4629, r_e=4.8682, n=3.2337, x_0=41.6152
# Sérsic 3: I_e=6.0593, r_e=10.0343, n=1.1339, x_0=65.0000
# Sérsic 4: I_e=9.4836, r_e=5.4606, n=0.3762, x_0=62.4411
# Sérsic 5: I_e=4.1243, r_e=4.3959, n=1.8662, x_0=72.6315
# Sérsic 6: I_e=2.2760, r_e=3.3538, n=0.7774, x_0=91.2238
# Chi quadro minimo: 123.31043015761126
# False

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha_diff", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=2.1936, r_e=8.1370, n=2.3920, x_0=16.7786
# Sérsic 2: I_e=2.4629, r_e=4.8682, n=3.2337, x_0=41.6152
# Sérsic 3: I_e=6.0593, r_e=10.0343, n=1.1339, x_0=65.0000
# Sérsic 4: I_e=9.4836, r_e=5.4606, n=0.3762, x_0=62.4411
# Sérsic 5: I_e=4.1243, r_e=4.3959, n=1.8662, x_0=72.6315
# Sérsic 6: I_e=2.2760, r_e=3.3538, n=0.7774, x_0=91.2238
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA, bounds = bounds_list, maxfev= 10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.0512, r_e=7.8307, n=2.5521, x_0=16.5114
# Sérsic 2: I_e=2.3900, r_e=5.2600, n=3.1575, x_0=41.6152
# Sérsic 3: I_e=5.9371, r_e=9.8445, n=1.1287, x_0=64.9756
# Sérsic 4: I_e=9.4749, r_e=5.4140, n=0.4391, x_0=62.4695
# Sérsic 5: I_e=4.1099, r_e=4.2790, n=1.9117, x_0=72.6706
# Sérsic 6: I_e=2.1174, r_e=4.0182, n=0.7572, x_0=91.4012
# [8.68884679e-01 2.01043038e+00 4.61877254e-01 6.62433955e-02
#  3.96776448e+00 5.17256546e+00 3.18593011e+00 5.00542846e-04
#  1.09260923e+01 6.56152030e+00 7.96553394e-01 9.44606945e-01
#  9.20238027e+00 1.75790382e+00 2.38280729e-01 2.76944251e+00
#  4.98598354e+00 3.58214663e+00 9.91922583e-01 1.77208756e-01
#  8.82857874e-01 1.56935009e+00 3.22526776e-01 2.42717980e-01]
# 6.613306814950427

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1, x_0_HA[0]+1),   # x_0: circa la posizione di Halpha

    (0, 10),
    (0, 10),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1, x_0_HA[2]+1),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-seeing[-1]/2, x_0_HA[3]+seeing[-1]/2),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[4]-seeing[-1]/2, x_0_HA[4]+seeing[-1]/2),

    (0, 0.1),
    (0, 5),
    (0.1, 10),
    (x_0_HA[5]-seeing[-1]/2, x_0_HA[5]+seeing[-1]/2),
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))
real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[2])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 57744.22707131743
# differential_evolution step 2: f(x)= 13239.427438916839
# differential_evolution step 3: f(x)= 8827.8961644449
# differential_evolution step 4: f(x)= 8827.8961644449
# differential_evolution step 5: f(x)= 8827.8961644449
# differential_evolution step 6: f(x)= 8827.8961644449
# differential_evolution step 7: f(x)= 8827.8961644449
# differential_evolution step 8: f(x)= 8827.8961644449
# differential_evolution step 9: f(x)= 8827.8961644449
# differential_evolution step 10: f(x)= 8827.8961644449
# differential_evolution step 11: f(x)= 4567.547928060915
# differential_evolution step 12: f(x)= 3386.1903065191705
# differential_evolution step 13: f(x)= 3386.1903065191705
# differential_evolution step 14: f(x)= 3386.1903065191705
# differential_evolution step 15: f(x)= 1282.0104940937965
# differential_evolution step 16: f(x)= 1282.0104940937965
# differential_evolution step 17: f(x)= 1282.0104940937965
# differential_evolution step 18: f(x)= 1282.0104940937965
# differential_evolution step 19: f(x)= 1282.0104940937965
# differential_evolution step 20: f(x)= 1282.0104940937965
# differential_evolution step 21: f(x)= 1282.0104940937965
# differential_evolution step 22: f(x)= 1282.0104940937965
# differential_evolution step 23: f(x)= 1282.0104940937965
# differential_evolution step 24: f(x)= 1282.0104940937965
# differential_evolution step 25: f(x)= 1282.0104940937965
# differential_evolution step 26: f(x)= 1282.0104940937965
# differential_evolution step 27: f(x)= 1282.0104940937965
# differential_evolution step 28: f(x)= 1145.6402208855834
# differential_evolution step 29: f(x)= 1145.6402208855834
# differential_evolution step 30: f(x)= 830.7715594693317
# differential_evolution step 31: f(x)= 830.7715594693317
# differential_evolution step 32: f(x)= 830.7715594693317
# differential_evolution step 33: f(x)= 830.7715594693317
# differential_evolution step 34: f(x)= 830.7715594693317
# differential_evolution step 35: f(x)= 397.7967257956605
# differential_evolution step 36: f(x)= 397.7967257956605
# differential_evolution step 37: f(x)= 397.7967257956605
# differential_evolution step 38: f(x)= 397.7967257956605
# differential_evolution step 39: f(x)= 397.7967257956605
# differential_evolution step 40: f(x)= 397.7967257956605
# differential_evolution step 41: f(x)= 397.7967257956605
# differential_evolution step 42: f(x)= 397.7967257956605
# differential_evolution step 43: f(x)= 304.047699532596
# differential_evolution step 44: f(x)= 304.047699532596
# differential_evolution step 45: f(x)= 304.047699532596
# differential_evolution step 46: f(x)= 304.047699532596
# differential_evolution step 47: f(x)= 304.047699532596
# differential_evolution step 48: f(x)= 304.047699532596
# differential_evolution step 49: f(x)= 304.047699532596
# differential_evolution step 50: f(x)= 278.7128881685707
# differential_evolution step 51: f(x)= 278.7128881685707
# differential_evolution step 52: f(x)= 278.7128881685707
# differential_evolution step 53: f(x)= 271.62791479861284
# differential_evolution step 54: f(x)= 271.62791479861284
# differential_evolution step 55: f(x)= 271.62791479861284
# differential_evolution step 56: f(x)= 271.62791479861284
# differential_evolution step 57: f(x)= 217.9969793679259
# differential_evolution step 58: f(x)= 217.9969793679259
# differential_evolution step 59: f(x)= 217.9969793679259
# differential_evolution step 60: f(x)= 217.9969793679259
# differential_evolution step 61: f(x)= 217.9969793679259
# differential_evolution step 62: f(x)= 217.9969793679259
# differential_evolution step 63: f(x)= 217.9969793679259
# differential_evolution step 64: f(x)= 217.9969793679259
# differential_evolution step 65: f(x)= 217.9969793679259
# differential_evolution step 66: f(x)= 217.9969793679259
# differential_evolution step 67: f(x)= 217.9969793679259
# differential_evolution step 68: f(x)= 217.9969793679259
# differential_evolution step 69: f(x)= 217.9969793679259
# differential_evolution step 70: f(x)= 217.9969793679259
# differential_evolution step 71: f(x)= 217.9969793679259
# differential_evolution step 72: f(x)= 217.9969793679259
# differential_evolution step 73: f(x)= 104.47254728198065
# differential_evolution step 74: f(x)= 104.47254728198065
# differential_evolution step 75: f(x)= 104.47254728198065
# differential_evolution step 76: f(x)= 104.47254728198065
# differential_evolution step 77: f(x)= 104.47254728198065
# differential_evolution step 78: f(x)= 104.47254728198065
# differential_evolution step 79: f(x)= 104.47254728198065
# differential_evolution step 80: f(x)= 104.47254728198065
# differential_evolution step 81: f(x)= 104.47254728198065
# differential_evolution step 82: f(x)= 104.47254728198065
# differential_evolution step 83: f(x)= 104.47254728198065
# differential_evolution step 84: f(x)= 104.47254728198065
# differential_evolution step 85: f(x)= 104.47254728198065
# differential_evolution step 86: f(x)= 104.47254728198065
# differential_evolution step 87: f(x)= 104.47254728198065
# differential_evolution step 88: f(x)= 104.47254728198065
# differential_evolution step 89: f(x)= 104.47254728198065
# differential_evolution step 90: f(x)= 104.47254728198065
# differential_evolution step 91: f(x)= 104.47254728198065
# differential_evolution step 92: f(x)= 104.47254728198065
# differential_evolution step 93: f(x)= 104.47254728198065
# differential_evolution step 94: f(x)= 104.47254728198065
# differential_evolution step 95: f(x)= 104.47254728198065
# differential_evolution step 96: f(x)= 104.47254728198065
# differential_evolution step 97: f(x)= 104.47254728198065
# differential_evolution step 98: f(x)= 104.47254728198065
# differential_evolution step 99: f(x)= 104.47254728198065
# differential_evolution step 100: f(x)= 104.47254728198065
# differential_evolution step 101: f(x)= 104.47254728198065
# differential_evolution step 102: f(x)= 104.47254728198065
# differential_evolution step 103: f(x)= 104.47254728198065
# differential_evolution step 104: f(x)= 104.47254728198065
# differential_evolution step 105: f(x)= 82.88425462059273
# differential_evolution step 106: f(x)= 82.88425462059273
# differential_evolution step 107: f(x)= 82.88425462059273
# differential_evolution step 108: f(x)= 82.88425462059273
# differential_evolution step 109: f(x)= 80.32856062715702
# differential_evolution step 110: f(x)= 80.32856062715702
# differential_evolution step 111: f(x)= 80.32856062715702
# differential_evolution step 112: f(x)= 80.32856062715702
# differential_evolution step 113: f(x)= 80.32856062715702
# differential_evolution step 114: f(x)= 80.32856062715702
# differential_evolution step 115: f(x)= 80.32856062715702
# differential_evolution step 116: f(x)= 80.32856062715702
# differential_evolution step 117: f(x)= 80.32856062715702
# differential_evolution step 118: f(x)= 80.32856062715702
# differential_evolution step 119: f(x)= 80.32856062715702
# differential_evolution step 120: f(x)= 80.32856062715702
# differential_evolution step 121: f(x)= 80.32856062715702
# differential_evolution step 122: f(x)= 80.32856062715702
# differential_evolution step 123: f(x)= 80.32856062715702
# differential_evolution step 124: f(x)= 80.32856062715702
# differential_evolution step 125: f(x)= 80.32856062715702
# differential_evolution step 126: f(x)= 80.32856062715702
# differential_evolution step 127: f(x)= 64.13429857948384
# differential_evolution step 128: f(x)= 64.13429857948384
# differential_evolution step 129: f(x)= 62.36837375536583
# differential_evolution step 130: f(x)= 62.36837375536583
# differential_evolution step 131: f(x)= 62.36837375536583
# differential_evolution step 132: f(x)= 62.36837375536583
# differential_evolution step 133: f(x)= 62.36837375536583
# differential_evolution step 134: f(x)= 62.36837375536583
# differential_evolution step 135: f(x)= 62.36837375536583
# differential_evolution step 136: f(x)= 62.36837375536583
# differential_evolution step 137: f(x)= 57.385883311935984
# differential_evolution step 138: f(x)= 57.385883311935984
# differential_evolution step 139: f(x)= 57.385883311935984
# differential_evolution step 140: f(x)= 57.385883311935984
# differential_evolution step 141: f(x)= 57.385883311935984
# differential_evolution step 142: f(x)= 57.385883311935984
# differential_evolution step 143: f(x)= 57.385883311935984
# differential_evolution step 144: f(x)= 57.385883311935984
# differential_evolution step 145: f(x)= 57.385883311935984
# differential_evolution step 146: f(x)= 57.385883311935984
# differential_evolution step 147: f(x)= 57.385883311935984
# differential_evolution step 148: f(x)= 57.385883311935984
# differential_evolution step 149: f(x)= 57.385883311935984
# differential_evolution step 150: f(x)= 57.385883311935984
# differential_evolution step 151: f(x)= 57.385883311935984
# differential_evolution step 152: f(x)= 57.385883311935984
# differential_evolution step 153: f(x)= 57.385883311935984
# differential_evolution step 154: f(x)= 57.385883311935984
# differential_evolution step 155: f(x)= 57.385883311935984
# differential_evolution step 156: f(x)= 45.42171123391465
# differential_evolution step 157: f(x)= 45.42171123391465
# differential_evolution step 158: f(x)= 45.42171123391465
# differential_evolution step 159: f(x)= 45.42171123391465
# differential_evolution step 160: f(x)= 45.42171123391465
# differential_evolution step 161: f(x)= 45.42171123391465
# differential_evolution step 162: f(x)= 45.42171123391465
# differential_evolution step 163: f(x)= 45.42171123391465
# differential_evolution step 164: f(x)= 45.42171123391465
# differential_evolution step 165: f(x)= 45.42171123391465
# differential_evolution step 166: f(x)= 45.42171123391465
# differential_evolution step 167: f(x)= 44.04532784836245
# differential_evolution step 168: f(x)= 44.04532784836245
# differential_evolution step 169: f(x)= 44.04532784836245
# differential_evolution step 170: f(x)= 44.04532784836245
# differential_evolution step 171: f(x)= 44.04532784836245
# differential_evolution step 172: f(x)= 44.04532784836245
# differential_evolution step 173: f(x)= 44.04532784836245
# differential_evolution step 174: f(x)= 44.04532784836245
# differential_evolution step 175: f(x)= 44.04532784836245
# differential_evolution step 176: f(x)= 44.04532784836245
# differential_evolution step 177: f(x)= 44.04532784836245
# differential_evolution step 178: f(x)= 44.04532784836245
# differential_evolution step 179: f(x)= 44.04532784836245
# differential_evolution step 180: f(x)= 44.04532784836245
# differential_evolution step 181: f(x)= 44.04532784836245
# differential_evolution step 182: f(x)= 35.347707764400155
# differential_evolution step 183: f(x)= 35.347707764400155
# differential_evolution step 184: f(x)= 35.347707764400155
# differential_evolution step 185: f(x)= 35.347707764400155
# differential_evolution step 186: f(x)= 35.347707764400155
# differential_evolution step 187: f(x)= 35.347707764400155
# differential_evolution step 188: f(x)= 35.347707764400155
# differential_evolution step 189: f(x)= 35.347707764400155
# differential_evolution step 190: f(x)= 35.347707764400155
# differential_evolution step 191: f(x)= 35.347707764400155
# differential_evolution step 192: f(x)= 35.347707764400155
# differential_evolution step 193: f(x)= 35.347707764400155
# differential_evolution step 194: f(x)= 35.347707764400155
# differential_evolution step 195: f(x)= 35.347707764400155
# differential_evolution step 196: f(x)= 35.347707764400155
# differential_evolution step 197: f(x)= 35.347707764400155
# differential_evolution step 198: f(x)= 35.347707764400155
# differential_evolution step 199: f(x)= 35.347707764400155
# differential_evolution step 200: f(x)= 35.347707764400155
# differential_evolution step 201: f(x)= 35.347707764400155
# differential_evolution step 202: f(x)= 35.347707764400155
# differential_evolution step 203: f(x)= 35.347707764400155
# differential_evolution step 204: f(x)= 35.347707764400155
# differential_evolution step 205: f(x)= 35.347707764400155
# differential_evolution step 206: f(x)= 35.347707764400155
# differential_evolution step 207: f(x)= 35.347707764400155
# differential_evolution step 208: f(x)= 35.347707764400155
# differential_evolution step 209: f(x)= 35.347707764400155
# differential_evolution step 210: f(x)= 35.347707764400155
# differential_evolution step 211: f(x)= 35.347707764400155
# differential_evolution step 212: f(x)= 35.32025594665509
# differential_evolution step 213: f(x)= 34.944692705091086
# differential_evolution step 214: f(x)= 34.944692705091086
# differential_evolution step 215: f(x)= 34.944692705091086
# differential_evolution step 216: f(x)= 34.944692705091086
# differential_evolution step 217: f(x)= 34.944692705091086
# differential_evolution step 218: f(x)= 34.944692705091086
# differential_evolution step 219: f(x)= 34.944692705091086
# differential_evolution step 220: f(x)= 34.944692705091086
# differential_evolution step 221: f(x)= 34.944692705091086
# differential_evolution step 222: f(x)= 27.246993839574287
# differential_evolution step 223: f(x)= 26.528981451493298
# differential_evolution step 224: f(x)= 26.528981451493298
# differential_evolution step 225: f(x)= 26.528981451493298
# differential_evolution step 226: f(x)= 26.528981451493298
# differential_evolution step 227: f(x)= 26.528981451493298
# differential_evolution step 228: f(x)= 26.528981451493298
# differential_evolution step 229: f(x)= 26.528981451493298
# differential_evolution step 230: f(x)= 26.528981451493298
# differential_evolution step 231: f(x)= 26.528981451493298
# differential_evolution step 232: f(x)= 26.528981451493298
# differential_evolution step 233: f(x)= 26.528981451493298
# differential_evolution step 234: f(x)= 26.528981451493298
# differential_evolution step 235: f(x)= 26.528981451493298
# differential_evolution step 236: f(x)= 26.528981451493298
# differential_evolution step 237: f(x)= 26.528981451493298
# differential_evolution step 238: f(x)= 26.528981451493298
# differential_evolution step 239: f(x)= 26.528981451493298
# differential_evolution step 240: f(x)= 26.528981451493298
# differential_evolution step 241: f(x)= 26.528981451493298
# differential_evolution step 242: f(x)= 26.528981451493298
# differential_evolution step 243: f(x)= 25.924718365320437
# differential_evolution step 244: f(x)= 25.924718365320437
# differential_evolution step 245: f(x)= 25.924718365320437
# differential_evolution step 246: f(x)= 25.048306872209846
# differential_evolution step 247: f(x)= 25.048306872209846
# differential_evolution step 248: f(x)= 20.599608773139536
# differential_evolution step 249: f(x)= 20.599608773139536
# differential_evolution step 250: f(x)= 20.599608773139536
# differential_evolution step 251: f(x)= 20.599608773139536
# differential_evolution step 252: f(x)= 20.599608773139536
# differential_evolution step 253: f(x)= 20.599608773139536
# differential_evolution step 254: f(x)= 20.599608773139536
# differential_evolution step 255: f(x)= 20.599608773139536
# differential_evolution step 256: f(x)= 20.599608773139536
# differential_evolution step 257: f(x)= 20.599608773139536
# differential_evolution step 258: f(x)= 19.23856476958759
# differential_evolution step 259: f(x)= 19.23856476958759
# differential_evolution step 260: f(x)= 19.23856476958759
# differential_evolution step 261: f(x)= 19.23856476958759
# differential_evolution step 262: f(x)= 19.23856476958759
# differential_evolution step 263: f(x)= 19.23856476958759
# differential_evolution step 264: f(x)= 19.23856476958759
# differential_evolution step 265: f(x)= 19.23856476958759
# differential_evolution step 266: f(x)= 19.23856476958759
# differential_evolution step 267: f(x)= 17.343464814479876
# differential_evolution step 268: f(x)= 17.343464814479876
# differential_evolution step 269: f(x)= 17.343464814479876
# differential_evolution step 270: f(x)= 17.343464814479876
# differential_evolution step 271: f(x)= 17.343464814479876
# differential_evolution step 272: f(x)= 17.343464814479876
# differential_evolution step 273: f(x)= 17.343464814479876
# differential_evolution step 274: f(x)= 17.343464814479876
# differential_evolution step 275: f(x)= 17.343464814479876
# differential_evolution step 276: f(x)= 17.343464814479876
# differential_evolution step 277: f(x)= 17.343464814479876
# differential_evolution step 278: f(x)= 17.343464814479876
# differential_evolution step 279: f(x)= 17.343464814479876
# differential_evolution step 280: f(x)= 17.343464814479876
# differential_evolution step 281: f(x)= 17.343464814479876
# differential_evolution step 282: f(x)= 17.343464814479876
# differential_evolution step 283: f(x)= 17.343464814479876
# differential_evolution step 284: f(x)= 17.343464814479876
# differential_evolution step 285: f(x)= 17.343464814479876
# differential_evolution step 286: f(x)= 17.343464814479876
# differential_evolution step 287: f(x)= 17.343464814479876
# differential_evolution step 288: f(x)= 17.343464814479876
# differential_evolution step 289: f(x)= 17.343464814479876
# differential_evolution step 290: f(x)= 17.343464814479876
# differential_evolution step 291: f(x)= 17.343464814479876
# differential_evolution step 292: f(x)= 17.343464814479876
# differential_evolution step 293: f(x)= 17.343464814479876
# differential_evolution step 294: f(x)= 17.343464814479876
# differential_evolution step 295: f(x)= 17.343464814479876
# differential_evolution step 296: f(x)= 17.343464814479876
# differential_evolution step 297: f(x)= 17.343464814479876
# differential_evolution step 298: f(x)= 17.343464814479876
# differential_evolution step 299: f(x)= 17.343464814479876
# differential_evolution step 300: f(x)= 17.343464814479876
# differential_evolution step 301: f(x)= 17.343464814479876
# differential_evolution step 302: f(x)= 17.343464814479876
# differential_evolution step 303: f(x)= 17.343464814479876
# differential_evolution step 304: f(x)= 17.343464814479876
# differential_evolution step 305: f(x)= 17.343464814479876
# differential_evolution step 306: f(x)= 17.343464814479876
# differential_evolution step 307: f(x)= 17.343464814479876
# differential_evolution step 308: f(x)= 17.343464814479876
# differential_evolution step 309: f(x)= 17.343464814479876
# differential_evolution step 310: f(x)= 16.90333471673075
# differential_evolution step 311: f(x)= 16.90333471673075
# differential_evolution step 312: f(x)= 16.557040509051365
# differential_evolution step 313: f(x)= 16.557040509051365
# differential_evolution step 314: f(x)= 16.557040509051365
# differential_evolution step 315: f(x)= 16.557040509051365
# differential_evolution step 316: f(x)= 16.557040509051365
# differential_evolution step 317: f(x)= 16.557040509051365
# differential_evolution step 318: f(x)= 16.557040509051365
# differential_evolution step 319: f(x)= 16.557040509051365
# differential_evolution step 320: f(x)= 16.557040509051365
# differential_evolution step 321: f(x)= 16.557040509051365
# differential_evolution step 322: f(x)= 16.557040509051365
# differential_evolution step 323: f(x)= 16.557040509051365
# differential_evolution step 324: f(x)= 16.557040509051365
# differential_evolution step 325: f(x)= 16.527392555613552
# differential_evolution step 326: f(x)= 16.527392555613552
# differential_evolution step 327: f(x)= 16.527392555613552
# differential_evolution step 328: f(x)= 16.527392555613552
# differential_evolution step 329: f(x)= 16.527392555613552
# differential_evolution step 330: f(x)= 16.527392555613552
# differential_evolution step 331: f(x)= 16.527392555613552
# differential_evolution step 332: f(x)= 16.527392555613552
# differential_evolution step 333: f(x)= 16.527392555613552
# differential_evolution step 334: f(x)= 15.612889817299664
# differential_evolution step 335: f(x)= 15.612889817299664
# differential_evolution step 336: f(x)= 15.612889817299664
# differential_evolution step 337: f(x)= 15.612889817299664
# differential_evolution step 338: f(x)= 15.612889817299664
# differential_evolution step 339: f(x)= 15.612889817299664
# differential_evolution step 340: f(x)= 15.612889817299664
# differential_evolution step 341: f(x)= 15.612889817299664
# differential_evolution step 342: f(x)= 15.612889817299664
# differential_evolution step 343: f(x)= 15.612889817299664
# differential_evolution step 344: f(x)= 15.612889817299664
# differential_evolution step 345: f(x)= 15.612889817299664
# differential_evolution step 346: f(x)= 14.119143945750375
# differential_evolution step 347: f(x)= 14.119143945750375
# differential_evolution step 348: f(x)= 14.119143945750375
# differential_evolution step 349: f(x)= 14.119143945750375
# differential_evolution step 350: f(x)= 14.119143945750375
# differential_evolution step 351: f(x)= 14.119143945750375
# differential_evolution step 352: f(x)= 14.119143945750375
# differential_evolution step 353: f(x)= 14.119143945750375
# differential_evolution step 354: f(x)= 14.119143945750375
# differential_evolution step 355: f(x)= 14.119143945750375
# differential_evolution step 356: f(x)= 14.119143945750375
# differential_evolution step 357: f(x)= 14.119143945750375
# differential_evolution step 358: f(x)= 14.119143945750375
# differential_evolution step 359: f(x)= 14.119143945750375
# differential_evolution step 360: f(x)= 14.119143945750375
# differential_evolution step 361: f(x)= 14.119143945750375
# differential_evolution step 362: f(x)= 14.11744327239508
# differential_evolution step 363: f(x)= 14.11744327239508
# differential_evolution step 364: f(x)= 14.049087768199811
# differential_evolution step 365: f(x)= 14.049087768199811
# differential_evolution step 366: f(x)= 14.049087768199811
# differential_evolution step 367: f(x)= 13.805129422775487
# differential_evolution step 368: f(x)= 13.805129422775487
# differential_evolution step 369: f(x)= 13.805129422775487
# differential_evolution step 370: f(x)= 13.805129422775487
# differential_evolution step 371: f(x)= 13.805129422775487
# differential_evolution step 372: f(x)= 13.805129422775487
# differential_evolution step 373: f(x)= 13.805129422775487
# differential_evolution step 374: f(x)= 13.805129422775487
# differential_evolution step 375: f(x)= 13.805129422775487
# differential_evolution step 376: f(x)= 13.805129422775487
# differential_evolution step 377: f(x)= 13.805129422775487
# differential_evolution step 378: f(x)= 13.76740225899355
# differential_evolution step 379: f(x)= 13.76740225899355
# differential_evolution step 380: f(x)= 13.76740225899355
# differential_evolution step 381: f(x)= 13.76740225899355
# differential_evolution step 382: f(x)= 13.76740225899355
# differential_evolution step 383: f(x)= 13.76740225899355
# differential_evolution step 384: f(x)= 13.76740225899355
# differential_evolution step 385: f(x)= 13.76740225899355
# differential_evolution step 386: f(x)= 13.76740225899355
# differential_evolution step 387: f(x)= 13.76740225899355
# differential_evolution step 388: f(x)= 13.76740225899355
# differential_evolution step 389: f(x)= 13.76740225899355
# differential_evolution step 390: f(x)= 13.293128958138253
# differential_evolution step 391: f(x)= 13.293128958138253
# differential_evolution step 392: f(x)= 13.293128958138253
# differential_evolution step 393: f(x)= 13.293128958138253
# differential_evolution step 394: f(x)= 13.293128958138253
# differential_evolution step 395: f(x)= 13.293128958138253
# differential_evolution step 396: f(x)= 13.293128958138253
# differential_evolution step 397: f(x)= 13.293128958138253
# differential_evolution step 398: f(x)= 13.293128958138253
# differential_evolution step 399: f(x)= 13.293128958138253
# differential_evolution step 400: f(x)= 13.293128958138253
# differential_evolution step 401: f(x)= 13.293128958138253
# differential_evolution step 402: f(x)= 13.293128958138253
# differential_evolution step 403: f(x)= 13.293128958138253
# differential_evolution step 404: f(x)= 13.293128958138253
# differential_evolution step 405: f(x)= 13.293128958138253
# differential_evolution step 406: f(x)= 13.293128958138253
# differential_evolution step 407: f(x)= 13.293128958138253
# differential_evolution step 408: f(x)= 13.293128958138253
# differential_evolution step 409: f(x)= 13.293128958138253
# differential_evolution step 410: f(x)= 13.293128958138253
# differential_evolution step 411: f(x)= 13.293128958138253
# differential_evolution step 412: f(x)= 13.293128958138253
# differential_evolution step 413: f(x)= 13.293128958138253
# differential_evolution step 414: f(x)= 13.293128958138253
# differential_evolution step 415: f(x)= 13.293128958138253
# differential_evolution step 416: f(x)= 13.293128958138253
# differential_evolution step 417: f(x)= 13.293128958138253
# differential_evolution step 418: f(x)= 13.293128958138253
# differential_evolution step 419: f(x)= 13.293128958138253
# differential_evolution step 420: f(x)= 13.293128958138253
# differential_evolution step 421: f(x)= 13.293128958138253
# differential_evolution step 422: f(x)= 13.293128958138253
# differential_evolution step 423: f(x)= 12.501855728481965
# differential_evolution step 424: f(x)= 12.501855728481965
# differential_evolution step 425: f(x)= 12.501855728481965
# differential_evolution step 426: f(x)= 12.501855728481965
# differential_evolution step 427: f(x)= 12.501855728481965
# differential_evolution step 428: f(x)= 12.328599905601955
# differential_evolution step 429: f(x)= 12.328599905601955
# differential_evolution step 430: f(x)= 11.426435258226068
# differential_evolution step 431: f(x)= 11.426435258226068
# differential_evolution step 432: f(x)= 11.426435258226068
# differential_evolution step 433: f(x)= 11.426435258226068
# differential_evolution step 434: f(x)= 11.426435258226068
# differential_evolution step 435: f(x)= 11.426435258226068
# differential_evolution step 436: f(x)= 11.426435258226068
# differential_evolution step 437: f(x)= 11.426435258226068
# differential_evolution step 438: f(x)= 11.426435258226068
# differential_evolution step 439: f(x)= 11.426435258226068
# differential_evolution step 440: f(x)= 11.426435258226068
# differential_evolution step 441: f(x)= 11.426435258226068
# differential_evolution step 442: f(x)= 11.426435258226068
# differential_evolution step 443: f(x)= 11.426435258226068
# differential_evolution step 444: f(x)= 11.426435258226068
# differential_evolution step 445: f(x)= 11.426435258226068
# differential_evolution step 446: f(x)= 11.426435258226068
# differential_evolution step 447: f(x)= 11.268893709137119
# differential_evolution step 448: f(x)= 11.268893709137119
# differential_evolution step 449: f(x)= 11.268893709137119
# differential_evolution step 450: f(x)= 11.268893709137119
# differential_evolution step 451: f(x)= 11.268893709137119
# differential_evolution step 452: f(x)= 11.268893709137119
# differential_evolution step 453: f(x)= 11.268893709137119
# differential_evolution step 454: f(x)= 11.268893709137119
# differential_evolution step 455: f(x)= 11.268893709137119
# differential_evolution step 456: f(x)= 11.268893709137119
# differential_evolution step 457: f(x)= 11.268893709137119
# differential_evolution step 458: f(x)= 11.268893709137119
# differential_evolution step 459: f(x)= 11.268893709137119
# differential_evolution step 460: f(x)= 11.268893709137119
# differential_evolution step 461: f(x)= 11.268893709137119
# differential_evolution step 462: f(x)= 11.268893709137119
# differential_evolution step 463: f(x)= 11.268893709137119
# differential_evolution step 464: f(x)= 11.268893709137119
# differential_evolution step 465: f(x)= 11.268893709137119
# differential_evolution step 466: f(x)= 11.268893709137119
# differential_evolution step 467: f(x)= 11.268893709137119
# differential_evolution step 468: f(x)= 11.268893709137119
# differential_evolution step 469: f(x)= 11.268893709137119
# differential_evolution step 470: f(x)= 11.268893709137119
# differential_evolution step 471: f(x)= 11.268893709137119
# differential_evolution step 472: f(x)= 11.268893709137119
# differential_evolution step 473: f(x)= 11.268893709137119
# differential_evolution step 474: f(x)= 11.268893709137119
# differential_evolution step 475: f(x)= 11.268893709137119
# differential_evolution step 476: f(x)= 11.268893709137119
# differential_evolution step 477: f(x)= 11.268893709137119
# differential_evolution step 478: f(x)= 11.268893709137119
# differential_evolution step 479: f(x)= 11.268893709137119
# differential_evolution step 480: f(x)= 11.268893709137119
# differential_evolution step 481: f(x)= 11.268893709137119
# differential_evolution step 482: f(x)= 11.268893709137119
# differential_evolution step 483: f(x)= 11.268893709137119
# differential_evolution step 484: f(x)= 11.268893709137119
# differential_evolution step 485: f(x)= 11.268893709137119
# differential_evolution step 486: f(x)= 11.268893709137119
# differential_evolution step 487: f(x)= 11.268893709137119
# differential_evolution step 488: f(x)= 11.268893709137119
# differential_evolution step 489: f(x)= 11.268893709137119
# differential_evolution step 490: f(x)= 11.268893709137119
# differential_evolution step 491: f(x)= 11.268893709137119
# differential_evolution step 492: f(x)= 11.268893709137119
# differential_evolution step 493: f(x)= 11.268893709137119
# differential_evolution step 494: f(x)= 11.268893709137119
# differential_evolution step 495: f(x)= 11.268893709137119
# differential_evolution step 496: f(x)= 11.268893709137119
# differential_evolution step 497: f(x)= 11.268893709137119
# differential_evolution step 498: f(x)= 11.268893709137119
# differential_evolution step 499: f(x)= 11.268893709137119
# differential_evolution step 500: f(x)= 11.268893709137119
# differential_evolution step 501: f(x)= 11.268893709137119
# differential_evolution step 502: f(x)= 11.268893709137119
# differential_evolution step 503: f(x)= 11.268893709137119
# differential_evolution step 504: f(x)= 11.268893709137119
# differential_evolution step 505: f(x)= 11.268893709137119
# differential_evolution step 506: f(x)= 11.268893709137119
# differential_evolution step 507: f(x)= 11.268893709137119
# differential_evolution step 508: f(x)= 11.268893709137119
# differential_evolution step 509: f(x)= 11.268893709137119
# differential_evolution step 510: f(x)= 11.268893709137119
# differential_evolution step 511: f(x)= 11.268893709137119
# differential_evolution step 512: f(x)= 11.268893709137119
# differential_evolution step 513: f(x)= 11.268893709137119
# differential_evolution step 514: f(x)= 11.268893709137119
# differential_evolution step 515: f(x)= 11.268893709137119
# differential_evolution step 516: f(x)= 11.268893709137119
# differential_evolution step 517: f(x)= 11.268893709137119
# differential_evolution step 518: f(x)= 11.268893709137119
# differential_evolution step 519: f(x)= 11.268893709137119
# differential_evolution step 520: f(x)= 11.268893709137119
# differential_evolution step 521: f(x)= 11.268893709137119
# differential_evolution step 522: f(x)= 11.268893709137119
# differential_evolution step 523: f(x)= 11.268893709137119
# differential_evolution step 524: f(x)= 11.268893709137119
# differential_evolution step 525: f(x)= 11.268893709137119
# differential_evolution step 526: f(x)= 11.268893709137119
# differential_evolution step 527: f(x)= 11.268893709137119
# differential_evolution step 528: f(x)= 11.268893709137119
# differential_evolution step 529: f(x)= 11.268893709137119
# differential_evolution step 530: f(x)= 11.268893709137119
# differential_evolution step 531: f(x)= 11.268893709137119
# differential_evolution step 532: f(x)= 11.268893709137119
# differential_evolution step 533: f(x)= 11.268893709137119
# differential_evolution step 534: f(x)= 11.268893709137119
# differential_evolution step 535: f(x)= 11.268893709137119
# differential_evolution step 536: f(x)= 11.268893709137119
# differential_evolution step 537: f(x)= 11.268893709137119
# differential_evolution step 538: f(x)= 11.268893709137119
# differential_evolution step 539: f(x)= 11.268893709137119
# differential_evolution step 540: f(x)= 11.268893709137119
# differential_evolution step 541: f(x)= 11.268893709137119
# differential_evolution step 542: f(x)= 11.268893709137119
# differential_evolution step 543: f(x)= 11.268893709137119
# differential_evolution step 544: f(x)= 11.268893709137119
# differential_evolution step 545: f(x)= 11.268893709137119
# differential_evolution step 546: f(x)= 11.268893709137119
# differential_evolution step 547: f(x)= 11.268893709137119
# differential_evolution step 548: f(x)= 11.268893709137119
# differential_evolution step 549: f(x)= 11.268893709137119
# differential_evolution step 550: f(x)= 11.268893709137119
# differential_evolution step 551: f(x)= 11.268893709137119
# differential_evolution step 552: f(x)= 11.268893709137119
# differential_evolution step 553: f(x)= 11.268893709137119
# differential_evolution step 554: f(x)= 11.14040134228625
# differential_evolution step 555: f(x)= 11.14040134228625
# differential_evolution step 556: f(x)= 11.14040134228625
# differential_evolution step 557: f(x)= 11.14040134228625
# differential_evolution step 558: f(x)= 11.14040134228625
# differential_evolution step 559: f(x)= 11.14040134228625
# differential_evolution step 560: f(x)= 11.14040134228625
# differential_evolution step 561: f(x)= 11.14040134228625
# differential_evolution step 562: f(x)= 11.14040134228625
# differential_evolution step 563: f(x)= 11.14040134228625
# differential_evolution step 564: f(x)= 11.14040134228625
# differential_evolution step 565: f(x)= 11.14040134228625
# differential_evolution step 566: f(x)= 11.14040134228625
# differential_evolution step 567: f(x)= 11.14040134228625
# differential_evolution step 568: f(x)= 11.14040134228625
# differential_evolution step 569: f(x)= 11.14040134228625
# differential_evolution step 570: f(x)= 11.14040134228625
# differential_evolution step 571: f(x)= 11.14040134228625
# differential_evolution step 572: f(x)= 11.14040134228625
# differential_evolution step 573: f(x)= 11.14040134228625
# differential_evolution step 574: f(x)= 11.124069807432322
# differential_evolution step 575: f(x)= 11.019676834946203
# differential_evolution step 576: f(x)= 11.019676834946203
# differential_evolution step 577: f(x)= 11.018596210785441
# differential_evolution step 578: f(x)= 11.018596210785441
# differential_evolution step 579: f(x)= 11.018596210785441
# differential_evolution step 580: f(x)= 11.018596210785441
# differential_evolution step 581: f(x)= 11.018596210785441
# differential_evolution step 582: f(x)= 11.018596210785441
# differential_evolution step 583: f(x)= 11.018596210785441
# differential_evolution step 584: f(x)= 11.018596210785441
# differential_evolution step 585: f(x)= 11.018596210785441
# differential_evolution step 586: f(x)= 11.018596210785441
# differential_evolution step 587: f(x)= 11.018596210785441
# differential_evolution step 588: f(x)= 11.018596210785441
# differential_evolution step 589: f(x)= 11.018596210785441
# differential_evolution step 590: f(x)= 11.018596210785441
# differential_evolution step 591: f(x)= 11.018596210785441
# differential_evolution step 592: f(x)= 11.018596210785441
# differential_evolution step 593: f(x)= 10.733562075672301
# differential_evolution step 594: f(x)= 10.733562075672301
# differential_evolution step 595: f(x)= 10.733562075672301
# differential_evolution step 596: f(x)= 10.733562075672301
# differential_evolution step 597: f(x)= 10.733562075672301
# differential_evolution step 598: f(x)= 10.733562075672301
# differential_evolution step 599: f(x)= 10.733562075672301
# differential_evolution step 600: f(x)= 10.733562075672301
# differential_evolution step 601: f(x)= 10.733562075672301
# differential_evolution step 602: f(x)= 10.733562075672301
# differential_evolution step 603: f(x)= 10.733562075672301
# differential_evolution step 604: f(x)= 10.733562075672301
# differential_evolution step 605: f(x)= 10.733562075672301
# differential_evolution step 606: f(x)= 10.733562075672301
# differential_evolution step 607: f(x)= 10.733562075672301
# differential_evolution step 608: f(x)= 10.733562075672301
# differential_evolution step 609: f(x)= 10.733562075672301
# differential_evolution step 610: f(x)= 10.733562075672301
# differential_evolution step 611: f(x)= 10.66060915418779
# differential_evolution step 612: f(x)= 10.66060915418779
# differential_evolution step 613: f(x)= 10.66060915418779
# differential_evolution step 614: f(x)= 10.66060915418779
# differential_evolution step 615: f(x)= 10.66060915418779
# differential_evolution step 616: f(x)= 10.66060915418779
# differential_evolution step 617: f(x)= 10.66060915418779
# differential_evolution step 618: f(x)= 10.66060915418779
# differential_evolution step 619: f(x)= 10.66060915418779
# differential_evolution step 620: f(x)= 10.66060915418779
# differential_evolution step 621: f(x)= 10.66060915418779
# differential_evolution step 622: f(x)= 10.66060915418779
# differential_evolution step 623: f(x)= 10.66060915418779
# differential_evolution step 624: f(x)= 10.66060915418779
# differential_evolution step 625: f(x)= 10.66060915418779
# differential_evolution step 626: f(x)= 10.66060915418779
# differential_evolution step 627: f(x)= 10.66060915418779
# differential_evolution step 628: f(x)= 10.66060915418779
# differential_evolution step 629: f(x)= 10.66060915418779
# differential_evolution step 630: f(x)= 10.66060915418779
# differential_evolution step 631: f(x)= 10.66060915418779
# differential_evolution step 632: f(x)= 10.66060915418779
# differential_evolution step 633: f(x)= 10.66060915418779
# differential_evolution step 634: f(x)= 10.66060915418779
# differential_evolution step 635: f(x)= 10.66060915418779
# differential_evolution step 636: f(x)= 10.66060915418779
# differential_evolution step 637: f(x)= 10.66060915418779
# differential_evolution step 638: f(x)= 10.282345093627507
# differential_evolution step 639: f(x)= 10.282345093627507
# differential_evolution step 640: f(x)= 10.282345093627507
# differential_evolution step 641: f(x)= 10.282345093627507
# differential_evolution step 642: f(x)= 10.282345093627507
# differential_evolution step 643: f(x)= 10.282345093627507
# differential_evolution step 644: f(x)= 10.282345093627507
# differential_evolution step 645: f(x)= 10.282345093627507
# differential_evolution step 646: f(x)= 10.282345093627507
# differential_evolution step 647: f(x)= 10.282345093627507
# differential_evolution step 648: f(x)= 10.282345093627507
# differential_evolution step 649: f(x)= 10.282345093627507
# differential_evolution step 650: f(x)= 10.282345093627507
# differential_evolution step 651: f(x)= 10.282345093627507
# differential_evolution step 652: f(x)= 10.282345093627507
# differential_evolution step 653: f(x)= 10.282345093627507
# differential_evolution step 654: f(x)= 10.282345093627507
# differential_evolution step 655: f(x)= 10.282345093627507
# differential_evolution step 656: f(x)= 10.282345093627507
# differential_evolution step 657: f(x)= 10.282345093627507
# differential_evolution step 658: f(x)= 10.282345093627507
# differential_evolution step 659: f(x)= 10.282345093627507
# differential_evolution step 660: f(x)= 10.282345093627507
# differential_evolution step 661: f(x)= 10.282345093627507
# differential_evolution step 662: f(x)= 10.282345093627507
# differential_evolution step 663: f(x)= 10.282345093627507
# differential_evolution step 664: f(x)= 10.282345093627507
# differential_evolution step 665: f(x)= 10.282345093627507
# differential_evolution step 666: f(x)= 10.282345093627507
# differential_evolution step 667: f(x)= 10.282345093627507
# differential_evolution step 668: f(x)= 10.282345093627507
# differential_evolution step 669: f(x)= 10.257905977322835
# differential_evolution step 670: f(x)= 10.257905977322835
# differential_evolution step 671: f(x)= 10.257905977322835
# differential_evolution step 672: f(x)= 10.257905977322835
# differential_evolution step 673: f(x)= 10.257905977322835
# differential_evolution step 674: f(x)= 10.257905977322835
# differential_evolution step 675: f(x)= 10.257905977322835
# differential_evolution step 676: f(x)= 10.257905977322835
# differential_evolution step 677: f(x)= 10.257905977322835
# differential_evolution step 678: f(x)= 10.257905977322835
# differential_evolution step 679: f(x)= 10.257905977322835
# differential_evolution step 680: f(x)= 10.257905977322835
# differential_evolution step 681: f(x)= 10.257905977322835
# differential_evolution step 682: f(x)= 10.257905977322835
# differential_evolution step 683: f(x)= 10.176764670243587
# differential_evolution step 684: f(x)= 10.176764670243587
# differential_evolution step 685: f(x)= 10.176764670243587
# differential_evolution step 686: f(x)= 10.176764670243587
# differential_evolution step 687: f(x)= 10.176764670243587
# differential_evolution step 688: f(x)= 10.176764670243587
# differential_evolution step 689: f(x)= 10.176764670243587
# differential_evolution step 690: f(x)= 10.176764670243587
# differential_evolution step 691: f(x)= 10.176764670243587
# differential_evolution step 692: f(x)= 10.176764670243587
# differential_evolution step 693: f(x)= 10.176764670243587
# differential_evolution step 694: f(x)= 10.176764670243587
# differential_evolution step 695: f(x)= 10.176764670243587
# differential_evolution step 696: f(x)= 10.176764670243587
# differential_evolution step 697: f(x)= 10.176764670243587
# differential_evolution step 698: f(x)= 10.176764670243587
# differential_evolution step 699: f(x)= 10.157541362354888
# differential_evolution step 700: f(x)= 10.157541362354888
# differential_evolution step 701: f(x)= 10.157541362354888
# differential_evolution step 702: f(x)= 10.157541362354888
# differential_evolution step 703: f(x)= 10.157541362354888
# differential_evolution step 704: f(x)= 10.157541362354888
# differential_evolution step 705: f(x)= 10.157541362354888
# differential_evolution step 706: f(x)= 10.157541362354888
# differential_evolution step 707: f(x)= 10.157541362354888
# differential_evolution step 708: f(x)= 10.157541362354888
# differential_evolution step 709: f(x)= 10.157541362354888
# differential_evolution step 710: f(x)= 10.157541362354888
# differential_evolution step 711: f(x)= 10.157541362354888
# differential_evolution step 712: f(x)= 10.157541362354888
# differential_evolution step 713: f(x)= 10.157541362354888
# differential_evolution step 714: f(x)= 10.157541362354888
# differential_evolution step 715: f(x)= 10.157541362354888
# differential_evolution step 716: f(x)= 9.86030068252456
# differential_evolution step 717: f(x)= 9.86030068252456
# differential_evolution step 718: f(x)= 9.86030068252456
# differential_evolution step 719: f(x)= 9.86030068252456
# differential_evolution step 720: f(x)= 9.86030068252456
# differential_evolution step 721: f(x)= 9.86030068252456
# differential_evolution step 722: f(x)= 9.86030068252456
# differential_evolution step 723: f(x)= 9.86030068252456
# differential_evolution step 724: f(x)= 9.86030068252456
# differential_evolution step 725: f(x)= 9.86030068252456
# differential_evolution step 726: f(x)= 9.86030068252456
# differential_evolution step 727: f(x)= 9.86030068252456
# differential_evolution step 728: f(x)= 9.86030068252456
# differential_evolution step 729: f(x)= 9.86030068252456
# differential_evolution step 730: f(x)= 9.86030068252456
# differential_evolution step 731: f(x)= 9.86030068252456
# differential_evolution step 732: f(x)= 9.86030068252456
# differential_evolution step 733: f(x)= 9.86030068252456
# differential_evolution step 734: f(x)= 9.86030068252456
# differential_evolution step 735: f(x)= 9.86030068252456
# differential_evolution step 736: f(x)= 9.86030068252456
# differential_evolution step 737: f(x)= 9.86030068252456
# differential_evolution step 738: f(x)= 9.86030068252456
# differential_evolution step 739: f(x)= 9.86030068252456
# differential_evolution step 740: f(x)= 9.86030068252456
# differential_evolution step 741: f(x)= 9.86030068252456
# differential_evolution step 742: f(x)= 9.86030068252456
# differential_evolution step 743: f(x)= 9.86030068252456
# differential_evolution step 744: f(x)= 9.86030068252456
# differential_evolution step 745: f(x)= 9.86030068252456
# differential_evolution step 746: f(x)= 9.86030068252456
# differential_evolution step 747: f(x)= 9.86030068252456
# differential_evolution step 748: f(x)= 9.86030068252456
# differential_evolution step 749: f(x)= 9.86030068252456
# differential_evolution step 750: f(x)= 9.86030068252456
# differential_evolution step 751: f(x)= 9.86030068252456
# differential_evolution step 752: f(x)= 9.86030068252456
# differential_evolution step 753: f(x)= 9.86030068252456
# differential_evolution step 754: f(x)= 9.86030068252456
# differential_evolution step 755: f(x)= 9.86030068252456
# differential_evolution step 756: f(x)= 9.86030068252456
# differential_evolution step 757: f(x)= 9.86030068252456
# differential_evolution step 758: f(x)= 9.86030068252456
# differential_evolution step 759: f(x)= 9.830751010752973
# differential_evolution step 760: f(x)= 9.830751010752973
# differential_evolution step 761: f(x)= 9.830751010752973
# differential_evolution step 762: f(x)= 9.830751010752973
# differential_evolution step 763: f(x)= 9.830751010752973
# differential_evolution step 764: f(x)= 9.830751010752973
# differential_evolution step 765: f(x)= 9.830751010752973
# differential_evolution step 766: f(x)= 9.830751010752973
# differential_evolution step 767: f(x)= 9.830751010752973
# differential_evolution step 768: f(x)= 9.830751010752973
# differential_evolution step 769: f(x)= 9.830751010752973
# differential_evolution step 770: f(x)= 9.830751010752973
# differential_evolution step 771: f(x)= 9.830751010752973
# differential_evolution step 772: f(x)= 9.830751010752973
# differential_evolution step 773: f(x)= 9.830751010752973
# differential_evolution step 774: f(x)= 9.830751010752973
# differential_evolution step 775: f(x)= 9.830751010752973
# differential_evolution step 776: f(x)= 9.815717125165726
# differential_evolution step 777: f(x)= 9.815717125165726
# differential_evolution step 778: f(x)= 9.815717125165726
# differential_evolution step 779: f(x)= 9.815717125165726
# differential_evolution step 780: f(x)= 9.815717125165726
# differential_evolution step 781: f(x)= 9.815717125165726
# differential_evolution step 782: f(x)= 9.815717125165726
# differential_evolution step 783: f(x)= 9.815717125165726
# differential_evolution step 784: f(x)= 9.815717125165726
# differential_evolution step 785: f(x)= 9.815717125165726
# differential_evolution step 786: f(x)= 9.815717125165726
# differential_evolution step 787: f(x)= 9.815717125165726
# differential_evolution step 788: f(x)= 9.815717125165726
# differential_evolution step 789: f(x)= 9.815717125165726
# differential_evolution step 790: f(x)= 9.815717125165726
# differential_evolution step 791: f(x)= 9.815717125165726
# differential_evolution step 792: f(x)= 9.815717125165726
# differential_evolution step 793: f(x)= 9.815717125165726
# differential_evolution step 794: f(x)= 9.815717125165726
# differential_evolution step 795: f(x)= 9.815717125165726
# differential_evolution step 796: f(x)= 9.815717125165726
# differential_evolution step 797: f(x)= 9.815717125165726
# differential_evolution step 798: f(x)= 9.815717125165726
# differential_evolution step 799: f(x)= 9.815717125165726
# differential_evolution step 800: f(x)= 9.815717125165726
# differential_evolution step 801: f(x)= 9.815717125165726
# differential_evolution step 802: f(x)= 9.815717125165726
# differential_evolution step 803: f(x)= 9.815717125165726
# differential_evolution step 804: f(x)= 9.815717125165726
# differential_evolution step 805: f(x)= 9.815717125165726
# differential_evolution step 806: f(x)= 9.815717125165726
# differential_evolution step 807: f(x)= 9.815717125165726
# differential_evolution step 808: f(x)= 9.815717125165726
# differential_evolution step 809: f(x)= 9.815717125165726
# differential_evolution step 810: f(x)= 9.815717125165726
# differential_evolution step 811: f(x)= 9.815717125165726
# differential_evolution step 812: f(x)= 9.815717125165726
# differential_evolution step 813: f(x)= 9.815717125165726
# differential_evolution step 814: f(x)= 9.815717125165726
# differential_evolution step 815: f(x)= 9.815717125165726
# differential_evolution step 816: f(x)= 9.815717125165726
# differential_evolution step 817: f(x)= 9.815717125165726
# differential_evolution step 818: f(x)= 9.815717125165726
# differential_evolution step 819: f(x)= 9.815717125165726
# differential_evolution step 820: f(x)= 9.815717125165726
# differential_evolution step 821: f(x)= 9.815717125165726
# differential_evolution step 822: f(x)= 9.815717125165726
# differential_evolution step 823: f(x)= 9.815717125165726
# differential_evolution step 824: f(x)= 9.815717125165726
# differential_evolution step 825: f(x)= 9.815717125165726
# differential_evolution step 826: f(x)= 9.677667058691002
# differential_evolution step 827: f(x)= 9.677667058691002
# differential_evolution step 828: f(x)= 9.677667058691002
# differential_evolution step 829: f(x)= 9.677667058691002
# differential_evolution step 830: f(x)= 9.677667058691002
# differential_evolution step 831: f(x)= 9.661045932308822
# differential_evolution step 832: f(x)= 9.661045932308822
# differential_evolution step 833: f(x)= 9.661045932308822
# differential_evolution step 834: f(x)= 9.661045932308822
# differential_evolution step 835: f(x)= 9.661045932308822
# differential_evolution step 836: f(x)= 9.661045932308822
# differential_evolution step 837: f(x)= 9.661045932308822
# differential_evolution step 838: f(x)= 9.661045932308822
# differential_evolution step 839: f(x)= 9.661045932308822
# differential_evolution step 840: f(x)= 9.661045932308822
# differential_evolution step 841: f(x)= 9.661045932308822
# differential_evolution step 842: f(x)= 9.661045932308822
# differential_evolution step 843: f(x)= 9.661045932308822
# differential_evolution step 844: f(x)= 9.661045932308822
# differential_evolution step 845: f(x)= 9.661045932308822
# differential_evolution step 846: f(x)= 9.661045932308822
# differential_evolution step 847: f(x)= 9.661045932308822
# differential_evolution step 848: f(x)= 9.661045932308822
# differential_evolution step 849: f(x)= 9.661045932308822
# differential_evolution step 850: f(x)= 9.661045932308822
# differential_evolution step 851: f(x)= 9.661045932308822
# differential_evolution step 852: f(x)= 9.554820898075485
# differential_evolution step 853: f(x)= 9.554820898075485
# differential_evolution step 854: f(x)= 9.554820898075485
# differential_evolution step 855: f(x)= 9.554820898075485
# differential_evolution step 856: f(x)= 9.554820898075485
# differential_evolution step 857: f(x)= 9.554820898075485
# differential_evolution step 858: f(x)= 9.554820898075485
# differential_evolution step 859: f(x)= 9.554820898075485
# differential_evolution step 860: f(x)= 9.554820898075485
# differential_evolution step 861: f(x)= 9.554820898075485
# differential_evolution step 862: f(x)= 9.554820898075485
# differential_evolution step 863: f(x)= 9.554820898075485
# differential_evolution step 864: f(x)= 9.526110530706777
# differential_evolution step 865: f(x)= 9.526110530706777
# differential_evolution step 866: f(x)= 9.526110530706777
# differential_evolution step 867: f(x)= 9.526110530706777
# differential_evolution step 868: f(x)= 9.526110530706777
# differential_evolution step 869: f(x)= 9.526110530706777
# differential_evolution step 870: f(x)= 9.526110530706777
# differential_evolution step 871: f(x)= 9.526110530706777
# differential_evolution step 872: f(x)= 9.526110530706777
# differential_evolution step 873: f(x)= 9.526110530706777
# differential_evolution step 874: f(x)= 9.526110530706777
# differential_evolution step 875: f(x)= 9.526110530706777
# differential_evolution step 876: f(x)= 9.526110530706777
# differential_evolution step 877: f(x)= 9.526110530706777
# differential_evolution step 878: f(x)= 9.526110530706777
# differential_evolution step 879: f(x)= 9.526110530706777
# differential_evolution step 880: f(x)= 9.526110530706777
# differential_evolution step 881: f(x)= 9.526110530706777
# differential_evolution step 882: f(x)= 9.526110530706777
# differential_evolution step 883: f(x)= 9.526110530706777
# differential_evolution step 884: f(x)= 9.526110530706777
# differential_evolution step 885: f(x)= 9.526110530706777
# differential_evolution step 886: f(x)= 9.526110530706777
# differential_evolution step 887: f(x)= 9.526110530706777
# differential_evolution step 888: f(x)= 9.526110530706777
# differential_evolution step 889: f(x)= 9.526110530706777
# differential_evolution step 890: f(x)= 9.526110530706777
# differential_evolution step 891: f(x)= 9.526110530706777
# differential_evolution step 892: f(x)= 9.526110530706777
# differential_evolution step 893: f(x)= 9.526110530706777
# differential_evolution step 894: f(x)= 9.526110530706777
# differential_evolution step 895: f(x)= 9.526110530706777
# differential_evolution step 896: f(x)= 9.526110530706777
# differential_evolution step 897: f(x)= 9.512344004088906
# differential_evolution step 898: f(x)= 9.512344004088906
# differential_evolution step 899: f(x)= 9.378527327812149
# differential_evolution step 900: f(x)= 9.378527327812149
# differential_evolution step 901: f(x)= 9.378527327812149
# differential_evolution step 902: f(x)= 9.378527327812149
# differential_evolution step 903: f(x)= 9.378527327812149
# differential_evolution step 904: f(x)= 9.378527327812149
# differential_evolution step 905: f(x)= 9.378527327812149
# differential_evolution step 906: f(x)= 9.378527327812149
# differential_evolution step 907: f(x)= 9.378527327812149
# differential_evolution step 908: f(x)= 9.378527327812149
# differential_evolution step 909: f(x)= 9.378527327812149
# differential_evolution step 910: f(x)= 9.378527327812149
# differential_evolution step 911: f(x)= 9.378527327812149
# differential_evolution step 912: f(x)= 9.378527327812149
# differential_evolution step 913: f(x)= 9.378527327812149
# differential_evolution step 914: f(x)= 9.378527327812149
# differential_evolution step 915: f(x)= 9.378527327812149
# differential_evolution step 916: f(x)= 9.378527327812149
# differential_evolution step 917: f(x)= 9.378527327812149
# differential_evolution step 918: f(x)= 9.378527327812149
# differential_evolution step 919: f(x)= 9.378527327812149
# differential_evolution step 920: f(x)= 9.378527327812149
# differential_evolution step 921: f(x)= 9.378527327812149
# differential_evolution step 922: f(x)= 9.378527327812149
# differential_evolution step 923: f(x)= 9.378527327812149
# differential_evolution step 924: f(x)= 9.378527327812149
# differential_evolution step 925: f(x)= 9.378527327812149
# differential_evolution step 926: f(x)= 9.378527327812149
# differential_evolution step 927: f(x)= 9.378527327812149
# differential_evolution step 928: f(x)= 9.378527327812149
# differential_evolution step 929: f(x)= 9.378527327812149
# differential_evolution step 930: f(x)= 9.378527327812149
# differential_evolution step 931: f(x)= 9.378527327812149
# differential_evolution step 932: f(x)= 9.378527327812149
# differential_evolution step 933: f(x)= 9.378527327812149
# differential_evolution step 934: f(x)= 9.378527327812149
# differential_evolution step 935: f(x)= 9.378527327812149
# differential_evolution step 936: f(x)= 9.378527327812149
# differential_evolution step 937: f(x)= 9.378527327812149
# differential_evolution step 938: f(x)= 9.378527327812149
# differential_evolution step 939: f(x)= 9.378527327812149
# differential_evolution step 940: f(x)= 9.378527327812149
# differential_evolution step 941: f(x)= 9.378527327812149
# differential_evolution step 942: f(x)= 9.378527327812149
# differential_evolution step 943: f(x)= 9.378527327812149
# differential_evolution step 944: f(x)= 9.378527327812149
# differential_evolution step 945: f(x)= 9.378527327812149
# differential_evolution step 946: f(x)= 9.378527327812149
# differential_evolution step 947: f(x)= 9.378527327812149
# differential_evolution step 948: f(x)= 9.378527327812149
# differential_evolution step 949: f(x)= 9.378527327812149
# differential_evolution step 950: f(x)= 9.378527327812149
# differential_evolution step 951: f(x)= 9.378527327812149
# differential_evolution step 952: f(x)= 9.378527327812149
# differential_evolution step 953: f(x)= 9.378527327812149
# differential_evolution step 954: f(x)= 9.378527327812149
# differential_evolution step 955: f(x)= 9.378527327812149
# differential_evolution step 956: f(x)= 9.378527327812149
# differential_evolution step 957: f(x)= 9.378527327812149
# differential_evolution step 958: f(x)= 9.378527327812149
# differential_evolution step 959: f(x)= 9.378527327812149
# differential_evolution step 960: f(x)= 9.378527327812149
# differential_evolution step 961: f(x)= 9.378527327812149
# differential_evolution step 962: f(x)= 9.378527327812149
# differential_evolution step 963: f(x)= 9.378527327812149
# differential_evolution step 964: f(x)= 9.378527327812149
# differential_evolution step 965: f(x)= 9.378527327812149
# differential_evolution step 966: f(x)= 9.378527327812149
# differential_evolution step 967: f(x)= 9.378527327812149
# differential_evolution step 968: f(x)= 9.378527327812149
# differential_evolution step 969: f(x)= 9.378527327812149
# differential_evolution step 970: f(x)= 9.378527327812149
# differential_evolution step 971: f(x)= 9.378527327812149
# differential_evolution step 972: f(x)= 9.378527327812149
# differential_evolution step 973: f(x)= 9.378527327812149
# differential_evolution step 974: f(x)= 9.378527327812149
# differential_evolution step 975: f(x)= 9.378527327812149
# differential_evolution step 976: f(x)= 9.378527327812149
# differential_evolution step 977: f(x)= 9.378527327812149
# differential_evolution step 978: f(x)= 9.378527327812149
# differential_evolution step 979: f(x)= 9.378527327812149
# differential_evolution step 980: f(x)= 9.378527327812149
# differential_evolution step 981: f(x)= 9.378527327812149
# differential_evolution step 982: f(x)= 9.378527327812149
# differential_evolution step 983: f(x)= 9.317091688921447
# differential_evolution step 984: f(x)= 9.317091688921447
# differential_evolution step 985: f(x)= 9.317091688921447
# differential_evolution step 986: f(x)= 9.317091688921447
# differential_evolution step 987: f(x)= 9.317091688921447
# differential_evolution step 988: f(x)= 9.317091688921447
# differential_evolution step 989: f(x)= 9.317091688921447
# differential_evolution step 990: f(x)= 9.317091688921447
# differential_evolution step 991: f(x)= 9.317091688921447
# differential_evolution step 992: f(x)= 9.317091688921447
# differential_evolution step 993: f(x)= 9.317091688921447
# differential_evolution step 994: f(x)= 9.317091688921447
# differential_evolution step 995: f(x)= 9.317091688921447
# differential_evolution step 996: f(x)= 9.317091688921447
# differential_evolution step 997: f(x)= 9.310799289785972
# differential_evolution step 998: f(x)= 9.310799289785972
# differential_evolution step 999: f(x)= 9.310799289785972
# differential_evolution step 1000: f(x)= 9.310799289785972
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.6142, r_e=9.4997, n=2.2283, x_0=16.0400
# Sérsic 2: I_e=6.7024, r_e=2.4111, n=2.7123, x_0=40.9784
# Sérsic 3: I_e=0.3555, r_e=42.2887, n=2.3183, x_0=65.9505
# Sérsic 4: I_e=3.6870, r_e=6.3394, n=0.5473, x_0=61.9618
# Sérsic 5: I_e=0.3188, r_e=4.4273, n=3.0619, x_0=72.1752
# Sérsic 6: I_e=0.0818, r_e=3.8771, n=2.8029, x_0=90.4518
# Chi quadro minimo: 9.107340303961456
# False

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Sérsic 1: I_e=0.6142, r_e=9.4997, n=2.2283, x_0=16.0400
# Sérsic 2: I_e=6.7024, r_e=2.4111, n=2.7123, x_0=40.9784
# Sérsic 3: I_e=0.3555, r_e=42.2887, n=2.3183, x_0=65.9505
# Sérsic 4: I_e=3.6870, r_e=6.3394, n=0.5473, x_0=61.9618
# Sérsic 5: I_e=0.3188, r_e=4.4273, n=3.0619, x_0=72.1752
# Sérsic 6: I_e=0.0818, r_e=3.8771, n=2.8029, x_0=90.4518
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB , bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.5564, r_e=9.9614, n=2.3156, x_0=15.9634
# Sérsic 2: I_e=4.8103, r_e=2.8587, n=3.0664, x_0=40.9752
# Sérsic 3: I_e=0.3021, r_e=46.5900, n=2.4677, x_0=65.8515
# Sérsic 4: I_e=3.7307, r_e=6.1347, n=0.5223, x_0=61.6593
# Sérsic 5: I_e=2.2043, r_e=1.9689, n=1.1011, x_0=72.1897
# Sérsic 6: I_e=0.1000, r_e=4.8949, n=2.2118, x_0=90.6311
# [4.24471525e-01 6.05560165e+00 5.72273706e-01 5.80286070e-02
#  2.71711287e+00 9.09978608e-01 6.51595331e-01 2.41112451e-02
#  5.57306215e-01 6.46135446e+01 1.60367909e+00 1.63885928e-02
#  1.49047017e+00 9.91318177e-01 1.10599848e-01 2.34513940e+00
#  1.92638128e+00 9.62417095e-01 7.39046818e-01 2.10328485e-01
#  7.47340898e-01 2.77120658e+01 5.78152891e+00 2.51237374e-01]
# 1.4099815940525864

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))
real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_0_HA[3]-seeing[-1]/2
# Out:
# 61.21047140622144

# %%
# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1, x_0_HA[0]+1),   # x_0: circa la posizione di Halpha

    (0, 10),
    (0, 10),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1, x_0_HA[2]+1),

    (0, 20),
    (0, 10),
    (0.1, 10),
    (x_0_HA[3]-seeing[-1]/2, x_0_HA[3]+seeing[-1]/2),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[4]-seeing[-1]/2, x_0_HA[4]+seeing[-1]/2),

    (0, 0.1),
    (0, 5),
    (0.1, 10),
    (x_0_HA[5]-seeing[-1]/2, x_0_HA[5]+seeing[-1]/2),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 68715.09644595762
# differential_evolution step 2: f(x)= 15874.48320316926
# differential_evolution step 3: f(x)= 5036.099129166478
# differential_evolution step 4: f(x)= 5036.099129166478
# differential_evolution step 5: f(x)= 5036.099129166478
# differential_evolution step 6: f(x)= 5036.099129166478
# differential_evolution step 7: f(x)= 5036.099129166478
# differential_evolution step 8: f(x)= 2969.8397901537915
# differential_evolution step 9: f(x)= 2969.8397901537915
# differential_evolution step 10: f(x)= 2969.8397901537915
# differential_evolution step 11: f(x)= 2969.8397901537915
# differential_evolution step 12: f(x)= 2914.713683877083
# differential_evolution step 13: f(x)= 2914.713683877083
# differential_evolution step 14: f(x)= 2914.713683877083
# differential_evolution step 15: f(x)= 2914.713683877083
# differential_evolution step 16: f(x)= 2914.713683877083
# differential_evolution step 17: f(x)= 2579.678129878953
# differential_evolution step 18: f(x)= 991.5964008310852
# differential_evolution step 19: f(x)= 890.7770174217902
# differential_evolution step 20: f(x)= 890.7770174217902
# differential_evolution step 21: f(x)= 890.7770174217902
# differential_evolution step 22: f(x)= 890.7770174217902
# differential_evolution step 23: f(x)= 890.7770174217902
# differential_evolution step 24: f(x)= 883.7316651345781
# differential_evolution step 25: f(x)= 883.7316651345781
# differential_evolution step 26: f(x)= 883.7316651345781
# differential_evolution step 27: f(x)= 883.7316651345781
# differential_evolution step 28: f(x)= 823.6755564974476
# differential_evolution step 29: f(x)= 823.6755564974476
# differential_evolution step 30: f(x)= 823.6755564974476
# differential_evolution step 31: f(x)= 823.6755564974476
# differential_evolution step 32: f(x)= 823.6755564974476
# differential_evolution step 33: f(x)= 819.0362325776525
# differential_evolution step 34: f(x)= 819.0362325776525
# differential_evolution step 35: f(x)= 819.0362325776525
# differential_evolution step 36: f(x)= 819.0362325776525
# differential_evolution step 37: f(x)= 819.0362325776525
# differential_evolution step 38: f(x)= 819.0362325776525
# differential_evolution step 39: f(x)= 819.0362325776525
# differential_evolution step 40: f(x)= 819.0362325776525
# differential_evolution step 41: f(x)= 819.0362325776525
# differential_evolution step 42: f(x)= 701.4585699480831
# differential_evolution step 43: f(x)= 701.4585699480831
# differential_evolution step 44: f(x)= 701.4585699480831
# differential_evolution step 45: f(x)= 574.4016397200694
# differential_evolution step 46: f(x)= 574.4016397200694
# differential_evolution step 47: f(x)= 427.771250376148
# differential_evolution step 48: f(x)= 427.771250376148
# differential_evolution step 49: f(x)= 427.771250376148
# differential_evolution step 50: f(x)= 418.1844539545429
# differential_evolution step 51: f(x)= 418.1844539545429
# differential_evolution step 52: f(x)= 418.1844539545429
# differential_evolution step 53: f(x)= 418.1844539545429
# differential_evolution step 54: f(x)= 418.1844539545429
# differential_evolution step 55: f(x)= 418.1844539545429
# differential_evolution step 56: f(x)= 418.1844539545429
# differential_evolution step 57: f(x)= 418.1844539545429
# differential_evolution step 58: f(x)= 418.1844539545429
# differential_evolution step 59: f(x)= 418.1844539545429
# differential_evolution step 60: f(x)= 418.1844539545429
# differential_evolution step 61: f(x)= 354.74977110712064
# differential_evolution step 62: f(x)= 354.74977110712064
# differential_evolution step 63: f(x)= 354.74977110712064
# differential_evolution step 64: f(x)= 354.74977110712064
# differential_evolution step 65: f(x)= 354.74977110712064
# differential_evolution step 66: f(x)= 354.74977110712064
# differential_evolution step 67: f(x)= 354.74977110712064
# differential_evolution step 68: f(x)= 354.74977110712064
# differential_evolution step 69: f(x)= 354.74977110712064
# differential_evolution step 70: f(x)= 354.74977110712064
# differential_evolution step 71: f(x)= 325.7065178329051
# differential_evolution step 72: f(x)= 325.7065178329051
# differential_evolution step 73: f(x)= 325.7065178329051
# differential_evolution step 74: f(x)= 325.7065178329051
# differential_evolution step 75: f(x)= 325.7065178329051
# differential_evolution step 76: f(x)= 325.7065178329051
# differential_evolution step 77: f(x)= 325.7065178329051
# differential_evolution step 78: f(x)= 325.7065178329051
# differential_evolution step 79: f(x)= 325.7065178329051
# differential_evolution step 80: f(x)= 325.7065178329051
# differential_evolution step 81: f(x)= 325.7065178329051
# differential_evolution step 82: f(x)= 325.7065178329051
# differential_evolution step 83: f(x)= 325.7065178329051
# differential_evolution step 84: f(x)= 325.7065178329051
# differential_evolution step 85: f(x)= 325.7065178329051
# differential_evolution step 86: f(x)= 325.7065178329051
# differential_evolution step 87: f(x)= 325.7065178329051
# differential_evolution step 88: f(x)= 325.7065178329051
# differential_evolution step 89: f(x)= 325.7065178329051
# differential_evolution step 90: f(x)= 325.7065178329051
# differential_evolution step 91: f(x)= 322.7955301837101
# differential_evolution step 92: f(x)= 291.89432863314073
# differential_evolution step 93: f(x)= 291.89432863314073
# differential_evolution step 94: f(x)= 291.89432863314073
# differential_evolution step 95: f(x)= 291.89432863314073
# differential_evolution step 96: f(x)= 291.89432863314073
# differential_evolution step 97: f(x)= 291.89432863314073
# differential_evolution step 98: f(x)= 291.89432863314073
# differential_evolution step 99: f(x)= 263.2363216680188
# differential_evolution step 100: f(x)= 263.2363216680188
# differential_evolution step 101: f(x)= 263.2363216680188
# differential_evolution step 102: f(x)= 263.2363216680188
# differential_evolution step 103: f(x)= 263.2363216680188
# differential_evolution step 104: f(x)= 263.2363216680188
# differential_evolution step 105: f(x)= 263.2363216680188
# differential_evolution step 106: f(x)= 263.2363216680188
# differential_evolution step 107: f(x)= 263.2363216680188
# differential_evolution step 108: f(x)= 196.39704774957966
# differential_evolution step 109: f(x)= 196.39704774957966
# differential_evolution step 110: f(x)= 196.39704774957966
# differential_evolution step 111: f(x)= 196.39704774957966
# differential_evolution step 112: f(x)= 196.39704774957966
# differential_evolution step 113: f(x)= 196.39704774957966
# differential_evolution step 114: f(x)= 196.39704774957966
# differential_evolution step 115: f(x)= 196.39704774957966
# differential_evolution step 116: f(x)= 196.39704774957966
# differential_evolution step 117: f(x)= 196.39704774957966
# differential_evolution step 118: f(x)= 196.39704774957966
# differential_evolution step 119: f(x)= 196.39704774957966
# differential_evolution step 120: f(x)= 196.39704774957966
# differential_evolution step 121: f(x)= 196.39704774957966
# differential_evolution step 122: f(x)= 196.39704774957966
# differential_evolution step 123: f(x)= 196.39704774957966
# differential_evolution step 124: f(x)= 196.39704774957966
# differential_evolution step 125: f(x)= 196.39704774957966
# differential_evolution step 126: f(x)= 196.39704774957966
# differential_evolution step 127: f(x)= 196.39704774957966
# differential_evolution step 128: f(x)= 196.39704774957966
# differential_evolution step 129: f(x)= 196.39704774957966
# differential_evolution step 130: f(x)= 196.39704774957966
# differential_evolution step 131: f(x)= 196.39704774957966
# differential_evolution step 132: f(x)= 177.1571293379331
# differential_evolution step 133: f(x)= 177.1571293379331
# differential_evolution step 134: f(x)= 177.1571293379331
# differential_evolution step 135: f(x)= 177.1571293379331
# differential_evolution step 136: f(x)= 177.1571293379331
# differential_evolution step 137: f(x)= 177.1571293379331
# differential_evolution step 138: f(x)= 177.1571293379331
# differential_evolution step 139: f(x)= 177.1571293379331
# differential_evolution step 140: f(x)= 176.06143558934693
# differential_evolution step 141: f(x)= 176.06143558934693
# differential_evolution step 142: f(x)= 176.06143558934693
# differential_evolution step 143: f(x)= 160.24276701184422
# differential_evolution step 144: f(x)= 160.24276701184422
# differential_evolution step 145: f(x)= 160.24276701184422
# differential_evolution step 146: f(x)= 160.24276701184422
# differential_evolution step 147: f(x)= 160.24276701184422
# differential_evolution step 148: f(x)= 160.24276701184422
# differential_evolution step 149: f(x)= 160.24276701184422
# differential_evolution step 150: f(x)= 160.24276701184422
# differential_evolution step 151: f(x)= 160.24276701184422
# differential_evolution step 152: f(x)= 160.24276701184422
# differential_evolution step 153: f(x)= 160.24276701184422
# differential_evolution step 154: f(x)= 160.24276701184422
# differential_evolution step 155: f(x)= 160.24276701184422
# differential_evolution step 156: f(x)= 160.24276701184422
# differential_evolution step 157: f(x)= 160.24276701184422
# differential_evolution step 158: f(x)= 160.24276701184422
# differential_evolution step 159: f(x)= 160.24276701184422
# differential_evolution step 160: f(x)= 152.57645125372514
# differential_evolution step 161: f(x)= 152.57645125372514
# differential_evolution step 162: f(x)= 152.57645125372514
# differential_evolution step 163: f(x)= 152.57645125372514
# differential_evolution step 164: f(x)= 152.57645125372514
# differential_evolution step 165: f(x)= 152.57645125372514
# differential_evolution step 166: f(x)= 152.57645125372514
# differential_evolution step 167: f(x)= 152.57645125372514
# differential_evolution step 168: f(x)= 152.57645125372514
# differential_evolution step 169: f(x)= 152.57645125372514
# differential_evolution step 170: f(x)= 134.97354553409087
# differential_evolution step 171: f(x)= 134.97354553409087
# differential_evolution step 172: f(x)= 134.97354553409087
# differential_evolution step 173: f(x)= 134.97354553409087
# differential_evolution step 174: f(x)= 134.97354553409087
# differential_evolution step 175: f(x)= 134.97354553409087
# differential_evolution step 176: f(x)= 134.97354553409087
# differential_evolution step 177: f(x)= 134.97354553409087
# differential_evolution step 178: f(x)= 134.97354553409087
# differential_evolution step 179: f(x)= 134.97354553409087
# differential_evolution step 180: f(x)= 128.6898799133532
# differential_evolution step 181: f(x)= 128.6898799133532
# differential_evolution step 182: f(x)= 128.6898799133532
# differential_evolution step 183: f(x)= 128.6898799133532
# differential_evolution step 184: f(x)= 128.6898799133532
# differential_evolution step 185: f(x)= 128.6898799133532
# differential_evolution step 186: f(x)= 128.6898799133532
# differential_evolution step 187: f(x)= 128.6898799133532
# differential_evolution step 188: f(x)= 128.6898799133532
# differential_evolution step 189: f(x)= 128.6898799133532
# differential_evolution step 190: f(x)= 128.6898799133532
# differential_evolution step 191: f(x)= 128.6898799133532
# differential_evolution step 192: f(x)= 128.6898799133532
# differential_evolution step 193: f(x)= 120.94106988235347
# differential_evolution step 194: f(x)= 120.94106988235347
# differential_evolution step 195: f(x)= 120.94106988235347
# differential_evolution step 196: f(x)= 120.94106988235347
# differential_evolution step 197: f(x)= 120.94106988235347
# differential_evolution step 198: f(x)= 120.94106988235347
# differential_evolution step 199: f(x)= 108.05225147764895
# differential_evolution step 200: f(x)= 108.05225147764895
# differential_evolution step 201: f(x)= 108.05225147764895
# differential_evolution step 202: f(x)= 108.05225147764895
# differential_evolution step 203: f(x)= 108.05225147764895
# differential_evolution step 204: f(x)= 108.05225147764895
# differential_evolution step 205: f(x)= 108.05225147764895
# differential_evolution step 206: f(x)= 108.05225147764895
# differential_evolution step 207: f(x)= 108.05225147764895
# differential_evolution step 208: f(x)= 108.05225147764895
# differential_evolution step 209: f(x)= 108.05225147764895
# differential_evolution step 210: f(x)= 108.05225147764895
# differential_evolution step 211: f(x)= 108.05225147764895
# differential_evolution step 212: f(x)= 89.04580428980748
# differential_evolution step 213: f(x)= 89.04580428980748
# differential_evolution step 214: f(x)= 89.04580428980748
# differential_evolution step 215: f(x)= 80.62902654932807
# differential_evolution step 216: f(x)= 80.62902654932807
# differential_evolution step 217: f(x)= 80.62902654932807
# differential_evolution step 218: f(x)= 80.62902654932807
# differential_evolution step 219: f(x)= 80.62902654932807
# differential_evolution step 220: f(x)= 80.62902654932807
# differential_evolution step 221: f(x)= 80.62902654932807
# differential_evolution step 222: f(x)= 80.62902654932807
# differential_evolution step 223: f(x)= 80.62902654932807
# differential_evolution step 224: f(x)= 80.62902654932807
# differential_evolution step 225: f(x)= 80.62902654932807
# differential_evolution step 226: f(x)= 80.62902654932807
# differential_evolution step 227: f(x)= 73.85318882501436
# differential_evolution step 228: f(x)= 73.85318882501436
# differential_evolution step 229: f(x)= 73.85318882501436
# differential_evolution step 230: f(x)= 73.85318882501436
# differential_evolution step 231: f(x)= 73.85318882501436
# differential_evolution step 232: f(x)= 73.85318882501436
# differential_evolution step 233: f(x)= 73.85318882501436
# differential_evolution step 234: f(x)= 73.85318882501436
# differential_evolution step 235: f(x)= 73.85318882501436
# differential_evolution step 236: f(x)= 73.85318882501436
# differential_evolution step 237: f(x)= 73.85318882501436
# differential_evolution step 238: f(x)= 73.85318882501436
# differential_evolution step 239: f(x)= 73.85318882501436
# differential_evolution step 240: f(x)= 71.6651834418704
# differential_evolution step 241: f(x)= 71.6651834418704
# differential_evolution step 242: f(x)= 66.61705761053638
# differential_evolution step 243: f(x)= 66.61705761053638
# differential_evolution step 244: f(x)= 66.61705761053638
# differential_evolution step 245: f(x)= 66.61705761053638
# differential_evolution step 246: f(x)= 66.61705761053638
# differential_evolution step 247: f(x)= 66.61705761053638
# differential_evolution step 248: f(x)= 66.21148359620751
# differential_evolution step 249: f(x)= 66.21148359620751
# differential_evolution step 250: f(x)= 66.21148359620751
# differential_evolution step 251: f(x)= 66.21148359620751
# differential_evolution step 252: f(x)= 66.21148359620751
# differential_evolution step 253: f(x)= 52.80218490035331
# differential_evolution step 254: f(x)= 52.80218490035331
# differential_evolution step 255: f(x)= 52.80218490035331
# differential_evolution step 256: f(x)= 52.80218490035331
# differential_evolution step 257: f(x)= 52.80218490035331
# differential_evolution step 258: f(x)= 52.80218490035331
# differential_evolution step 259: f(x)= 52.80218490035331
# differential_evolution step 260: f(x)= 52.80218490035331
# differential_evolution step 261: f(x)= 52.80218490035331
# differential_evolution step 262: f(x)= 52.80218490035331
# differential_evolution step 263: f(x)= 52.80218490035331
# differential_evolution step 264: f(x)= 52.80218490035331
# differential_evolution step 265: f(x)= 52.80218490035331
# differential_evolution step 266: f(x)= 52.80218490035331
# differential_evolution step 267: f(x)= 52.80218490035331
# differential_evolution step 268: f(x)= 52.80218490035331
# differential_evolution step 269: f(x)= 52.80218490035331
# differential_evolution step 270: f(x)= 52.80218490035331
# differential_evolution step 271: f(x)= 52.80218490035331
# differential_evolution step 272: f(x)= 51.67627441712963
# differential_evolution step 273: f(x)= 51.67627441712963
# differential_evolution step 274: f(x)= 51.67627441712963
# differential_evolution step 275: f(x)= 51.67627441712963
# differential_evolution step 276: f(x)= 51.67627441712963
# differential_evolution step 277: f(x)= 51.67627441712963
# differential_evolution step 278: f(x)= 50.939353834356424
# differential_evolution step 279: f(x)= 50.939353834356424
# differential_evolution step 280: f(x)= 50.939353834356424
# differential_evolution step 281: f(x)= 50.939353834356424
# differential_evolution step 282: f(x)= 50.939353834356424
# differential_evolution step 283: f(x)= 50.939353834356424
# differential_evolution step 284: f(x)= 50.939353834356424
# differential_evolution step 285: f(x)= 50.939353834356424
# differential_evolution step 286: f(x)= 50.939353834356424
# differential_evolution step 287: f(x)= 50.939353834356424
# differential_evolution step 288: f(x)= 50.939353834356424
# differential_evolution step 289: f(x)= 50.939353834356424
# differential_evolution step 290: f(x)= 50.939353834356424
# differential_evolution step 291: f(x)= 50.939353834356424
# differential_evolution step 292: f(x)= 50.939353834356424
# differential_evolution step 293: f(x)= 50.939353834356424
# differential_evolution step 294: f(x)= 50.939353834356424
# differential_evolution step 295: f(x)= 48.52406408752749
# differential_evolution step 296: f(x)= 48.38808238743045
# differential_evolution step 297: f(x)= 48.38808238743045
# differential_evolution step 298: f(x)= 48.38808238743045
# differential_evolution step 299: f(x)= 46.31876256747502
# differential_evolution step 300: f(x)= 46.31876256747502
# differential_evolution step 301: f(x)= 46.31876256747502
# differential_evolution step 302: f(x)= 46.31876256747502
# differential_evolution step 303: f(x)= 46.31876256747502
# differential_evolution step 304: f(x)= 46.31876256747502
# differential_evolution step 305: f(x)= 42.021410178101014
# differential_evolution step 306: f(x)= 42.021410178101014
# differential_evolution step 307: f(x)= 42.021410178101014
# differential_evolution step 308: f(x)= 42.021410178101014
# differential_evolution step 309: f(x)= 42.021410178101014
# differential_evolution step 310: f(x)= 42.021410178101014
# differential_evolution step 311: f(x)= 42.021410178101014
# differential_evolution step 312: f(x)= 42.021410178101014
# differential_evolution step 313: f(x)= 41.22587708097159
# differential_evolution step 314: f(x)= 41.22587708097159
# differential_evolution step 315: f(x)= 41.22587708097159
# differential_evolution step 316: f(x)= 41.22587708097159
# differential_evolution step 317: f(x)= 41.22587708097159
# differential_evolution step 318: f(x)= 41.22587708097159
# differential_evolution step 319: f(x)= 41.22587708097159
# differential_evolution step 320: f(x)= 41.22587708097159
# differential_evolution step 321: f(x)= 40.221208473416176
# differential_evolution step 322: f(x)= 40.221208473416176
# differential_evolution step 323: f(x)= 40.221208473416176
# differential_evolution step 324: f(x)= 40.221208473416176
# differential_evolution step 325: f(x)= 40.221208473416176
# differential_evolution step 326: f(x)= 38.00194657229236
# differential_evolution step 327: f(x)= 38.00194657229236
# differential_evolution step 328: f(x)= 38.00194657229236
# differential_evolution step 329: f(x)= 38.00194657229236
# differential_evolution step 330: f(x)= 38.00194657229236
# differential_evolution step 331: f(x)= 38.00194657229236
# differential_evolution step 332: f(x)= 38.00194657229236
# differential_evolution step 333: f(x)= 38.00194657229236
# differential_evolution step 334: f(x)= 38.00194657229236
# differential_evolution step 335: f(x)= 38.00194657229236
# differential_evolution step 336: f(x)= 38.00194657229236
# differential_evolution step 337: f(x)= 38.00194657229236
# differential_evolution step 338: f(x)= 38.00194657229236
# differential_evolution step 339: f(x)= 37.56808158030929
# differential_evolution step 340: f(x)= 37.56808158030929
# differential_evolution step 341: f(x)= 37.56808158030929
# differential_evolution step 342: f(x)= 37.56808158030929
# differential_evolution step 343: f(x)= 37.56808158030929
# differential_evolution step 344: f(x)= 37.56808158030929
# differential_evolution step 345: f(x)= 37.56808158030929
# differential_evolution step 346: f(x)= 37.56808158030929
# differential_evolution step 347: f(x)= 37.56808158030929
# differential_evolution step 348: f(x)= 37.56808158030929
# differential_evolution step 349: f(x)= 37.56808158030929
# differential_evolution step 350: f(x)= 37.56808158030929
# differential_evolution step 351: f(x)= 37.56808158030929
# differential_evolution step 352: f(x)= 37.56808158030929
# differential_evolution step 353: f(x)= 37.56808158030929
# differential_evolution step 354: f(x)= 37.56808158030929
# differential_evolution step 355: f(x)= 37.56808158030929
# differential_evolution step 356: f(x)= 37.56808158030929
# differential_evolution step 357: f(x)= 37.56808158030929
# differential_evolution step 358: f(x)= 37.56808158030929
# differential_evolution step 359: f(x)= 36.71695616583723
# differential_evolution step 360: f(x)= 34.057708610724994
# differential_evolution step 361: f(x)= 34.057708610724994
# differential_evolution step 362: f(x)= 34.057708610724994
# differential_evolution step 363: f(x)= 34.057708610724994
# differential_evolution step 364: f(x)= 34.057708610724994
# differential_evolution step 365: f(x)= 34.057708610724994
# differential_evolution step 366: f(x)= 31.910127801803934
# differential_evolution step 367: f(x)= 31.910127801803934
# differential_evolution step 368: f(x)= 31.910127801803934
# differential_evolution step 369: f(x)= 31.910127801803934
# differential_evolution step 370: f(x)= 31.910127801803934
# differential_evolution step 371: f(x)= 31.910127801803934
# differential_evolution step 372: f(x)= 31.910127801803934
# differential_evolution step 373: f(x)= 31.910127801803934
# differential_evolution step 374: f(x)= 31.910127801803934
# differential_evolution step 375: f(x)= 31.910127801803934
# differential_evolution step 376: f(x)= 31.910127801803934
# differential_evolution step 377: f(x)= 31.910127801803934
# differential_evolution step 378: f(x)= 31.910127801803934
# differential_evolution step 379: f(x)= 31.910127801803934
# differential_evolution step 380: f(x)= 31.910127801803934
# differential_evolution step 381: f(x)= 31.910127801803934
# differential_evolution step 382: f(x)= 31.910127801803934
# differential_evolution step 383: f(x)= 31.689436321598524
# differential_evolution step 384: f(x)= 31.689436321598524
# differential_evolution step 385: f(x)= 31.689436321598524
# differential_evolution step 386: f(x)= 31.689436321598524
# differential_evolution step 387: f(x)= 31.689436321598524
# differential_evolution step 388: f(x)= 31.689436321598524
# differential_evolution step 389: f(x)= 31.689436321598524
# differential_evolution step 390: f(x)= 31.689436321598524
# differential_evolution step 391: f(x)= 31.689436321598524
# differential_evolution step 392: f(x)= 31.689436321598524
# differential_evolution step 393: f(x)= 31.689436321598524
# differential_evolution step 394: f(x)= 31.689436321598524
# differential_evolution step 395: f(x)= 31.689436321598524
# differential_evolution step 396: f(x)= 31.689436321598524
# differential_evolution step 397: f(x)= 31.689436321598524
# differential_evolution step 398: f(x)= 31.689436321598524
# differential_evolution step 399: f(x)= 31.689436321598524
# differential_evolution step 400: f(x)= 31.689436321598524
# differential_evolution step 401: f(x)= 31.689436321598524
# differential_evolution step 402: f(x)= 31.689436321598524
# differential_evolution step 403: f(x)= 31.689436321598524
# differential_evolution step 404: f(x)= 28.685080263089283
# differential_evolution step 405: f(x)= 28.685080263089283
# differential_evolution step 406: f(x)= 28.685080263089283
# differential_evolution step 407: f(x)= 28.685080263089283
# differential_evolution step 408: f(x)= 28.685080263089283
# differential_evolution step 409: f(x)= 28.685080263089283
# differential_evolution step 410: f(x)= 28.685080263089283
# differential_evolution step 411: f(x)= 28.685080263089283
# differential_evolution step 412: f(x)= 28.685080263089283
# differential_evolution step 413: f(x)= 28.685080263089283
# differential_evolution step 414: f(x)= 28.685080263089283
# differential_evolution step 415: f(x)= 28.685080263089283
# differential_evolution step 416: f(x)= 28.685080263089283
# differential_evolution step 417: f(x)= 28.685080263089283
# differential_evolution step 418: f(x)= 28.685080263089283
# differential_evolution step 419: f(x)= 28.685080263089283
# differential_evolution step 420: f(x)= 28.685080263089283
# differential_evolution step 421: f(x)= 28.685080263089283
# differential_evolution step 422: f(x)= 28.685080263089283
# differential_evolution step 423: f(x)= 28.685080263089283
# differential_evolution step 424: f(x)= 28.685080263089283
# differential_evolution step 425: f(x)= 28.685080263089283
# differential_evolution step 426: f(x)= 28.685080263089283
# differential_evolution step 427: f(x)= 28.685080263089283
# differential_evolution step 428: f(x)= 28.685080263089283
# differential_evolution step 429: f(x)= 28.685080263089283
# differential_evolution step 430: f(x)= 28.685080263089283
# differential_evolution step 431: f(x)= 28.685080263089283
# differential_evolution step 432: f(x)= 28.685080263089283
# differential_evolution step 433: f(x)= 28.685080263089283
# differential_evolution step 434: f(x)= 28.685080263089283
# differential_evolution step 435: f(x)= 28.685080263089283
# differential_evolution step 436: f(x)= 28.685080263089283
# differential_evolution step 437: f(x)= 28.685080263089283
# differential_evolution step 438: f(x)= 28.685080263089283
# differential_evolution step 439: f(x)= 28.685080263089283
# differential_evolution step 440: f(x)= 28.685080263089283
# differential_evolution step 441: f(x)= 28.685080263089283
# differential_evolution step 442: f(x)= 28.685080263089283
# differential_evolution step 443: f(x)= 28.685080263089283
# differential_evolution step 444: f(x)= 28.685080263089283
# differential_evolution step 445: f(x)= 28.685080263089283
# differential_evolution step 446: f(x)= 28.685080263089283
# differential_evolution step 447: f(x)= 28.685080263089283
# differential_evolution step 448: f(x)= 28.685080263089283
# differential_evolution step 449: f(x)= 28.685080263089283
# differential_evolution step 450: f(x)= 28.685080263089283
# differential_evolution step 451: f(x)= 28.685080263089283
# differential_evolution step 452: f(x)= 28.685080263089283
# differential_evolution step 453: f(x)= 28.685080263089283
# differential_evolution step 454: f(x)= 28.685080263089283
# differential_evolution step 455: f(x)= 28.685080263089283
# differential_evolution step 456: f(x)= 28.685080263089283
# differential_evolution step 457: f(x)= 28.685080263089283
# differential_evolution step 458: f(x)= 28.685080263089283
# differential_evolution step 459: f(x)= 28.685080263089283
# differential_evolution step 460: f(x)= 28.685080263089283
# differential_evolution step 461: f(x)= 27.97997412748949
# differential_evolution step 462: f(x)= 27.97997412748949
# differential_evolution step 463: f(x)= 27.97997412748949
# differential_evolution step 464: f(x)= 27.97997412748949
# differential_evolution step 465: f(x)= 27.97997412748949
# differential_evolution step 466: f(x)= 27.97997412748949
# differential_evolution step 467: f(x)= 27.97997412748949
# differential_evolution step 468: f(x)= 27.97997412748949
# differential_evolution step 469: f(x)= 27.97997412748949
# differential_evolution step 470: f(x)= 27.97997412748949
# differential_evolution step 471: f(x)= 27.97997412748949
# differential_evolution step 472: f(x)= 26.84730866718687
# differential_evolution step 473: f(x)= 26.84730866718687
# differential_evolution step 474: f(x)= 26.84730866718687
# differential_evolution step 475: f(x)= 26.84730866718687
# differential_evolution step 476: f(x)= 26.84730866718687
# differential_evolution step 477: f(x)= 26.84730866718687
# differential_evolution step 478: f(x)= 26.84730866718687
# differential_evolution step 479: f(x)= 26.84730866718687
# differential_evolution step 480: f(x)= 26.84730866718687
# differential_evolution step 481: f(x)= 26.84730866718687
# differential_evolution step 482: f(x)= 26.84730866718687
# differential_evolution step 483: f(x)= 26.84730866718687
# differential_evolution step 484: f(x)= 26.84730866718687
# differential_evolution step 485: f(x)= 26.84730866718687
# differential_evolution step 486: f(x)= 26.84730866718687
# differential_evolution step 487: f(x)= 25.97618783170672
# differential_evolution step 488: f(x)= 25.97618783170672
# differential_evolution step 489: f(x)= 25.97618783170672
# differential_evolution step 490: f(x)= 25.97618783170672
# differential_evolution step 491: f(x)= 25.97618783170672
# differential_evolution step 492: f(x)= 25.97618783170672
# differential_evolution step 493: f(x)= 25.97618783170672
# differential_evolution step 494: f(x)= 25.97618783170672
# differential_evolution step 495: f(x)= 25.97618783170672
# differential_evolution step 496: f(x)= 25.97618783170672
# differential_evolution step 497: f(x)= 25.97618783170672
# differential_evolution step 498: f(x)= 25.97618783170672
# differential_evolution step 499: f(x)= 25.897829748096022
# differential_evolution step 500: f(x)= 25.897829748096022
# differential_evolution step 501: f(x)= 25.897829748096022
# differential_evolution step 502: f(x)= 25.897829748096022
# differential_evolution step 503: f(x)= 25.897829748096022
# differential_evolution step 504: f(x)= 25.897829748096022
# differential_evolution step 505: f(x)= 25.324453331595805
# differential_evolution step 506: f(x)= 25.324453331595805
# differential_evolution step 507: f(x)= 25.324453331595805
# differential_evolution step 508: f(x)= 25.324453331595805
# differential_evolution step 509: f(x)= 24.778370544657566
# differential_evolution step 510: f(x)= 24.778370544657566
# differential_evolution step 511: f(x)= 24.778370544657566
# differential_evolution step 512: f(x)= 24.762682634222713
# differential_evolution step 513: f(x)= 24.762682634222713
# differential_evolution step 514: f(x)= 24.762682634222713
# differential_evolution step 515: f(x)= 24.762682634222713
# differential_evolution step 516: f(x)= 24.762682634222713
# differential_evolution step 517: f(x)= 24.762682634222713
# differential_evolution step 518: f(x)= 24.762682634222713
# differential_evolution step 519: f(x)= 24.762682634222713
# differential_evolution step 520: f(x)= 24.762682634222713
# differential_evolution step 521: f(x)= 24.762682634222713
# differential_evolution step 522: f(x)= 24.141768474998592
# differential_evolution step 523: f(x)= 24.141768474998592
# differential_evolution step 524: f(x)= 24.141768474998592
# differential_evolution step 525: f(x)= 24.141768474998592
# differential_evolution step 526: f(x)= 24.141768474998592
# differential_evolution step 527: f(x)= 24.141768474998592
# differential_evolution step 528: f(x)= 24.141768474998592
# differential_evolution step 529: f(x)= 24.141768474998592
# differential_evolution step 530: f(x)= 24.141768474998592
# differential_evolution step 531: f(x)= 24.141768474998592
# differential_evolution step 532: f(x)= 24.141768474998592
# differential_evolution step 533: f(x)= 24.141768474998592
# differential_evolution step 534: f(x)= 24.141768474998592
# differential_evolution step 535: f(x)= 24.141768474998592
# differential_evolution step 536: f(x)= 24.141768474998592
# differential_evolution step 537: f(x)= 24.141768474998592
# differential_evolution step 538: f(x)= 24.141768474998592
# differential_evolution step 539: f(x)= 24.141768474998592
# differential_evolution step 540: f(x)= 24.141768474998592
# differential_evolution step 541: f(x)= 24.141768474998592
# differential_evolution step 542: f(x)= 24.141768474998592
# differential_evolution step 543: f(x)= 24.141768474998592
# differential_evolution step 544: f(x)= 24.141768474998592
# differential_evolution step 545: f(x)= 24.141768474998592
# differential_evolution step 546: f(x)= 24.141768474998592
# differential_evolution step 547: f(x)= 24.141768474998592
# differential_evolution step 548: f(x)= 24.141768474998592
# differential_evolution step 549: f(x)= 24.141768474998592
# differential_evolution step 550: f(x)= 24.000622955406893
# differential_evolution step 551: f(x)= 24.000622955406893
# differential_evolution step 552: f(x)= 23.821523297491844
# differential_evolution step 553: f(x)= 23.821523297491844
# differential_evolution step 554: f(x)= 23.821523297491844
# differential_evolution step 555: f(x)= 23.821523297491844
# differential_evolution step 556: f(x)= 23.821523297491844
# differential_evolution step 557: f(x)= 23.821523297491844
# differential_evolution step 558: f(x)= 23.821523297491844
# differential_evolution step 559: f(x)= 23.821523297491844
# differential_evolution step 560: f(x)= 23.821523297491844
# differential_evolution step 561: f(x)= 23.821523297491844
# differential_evolution step 562: f(x)= 23.821523297491844
# differential_evolution step 563: f(x)= 23.821523297491844
# differential_evolution step 564: f(x)= 23.821523297491844
# differential_evolution step 565: f(x)= 23.682602811337087
# differential_evolution step 566: f(x)= 23.682602811337087
# differential_evolution step 567: f(x)= 23.059691240304364
# differential_evolution step 568: f(x)= 23.059691240304364
# differential_evolution step 569: f(x)= 23.059691240304364
# differential_evolution step 570: f(x)= 23.059691240304364
# differential_evolution step 571: f(x)= 22.973932848862958
# differential_evolution step 572: f(x)= 22.973932848862958
# differential_evolution step 573: f(x)= 22.973932848862958
# differential_evolution step 574: f(x)= 22.973932848862958
# differential_evolution step 575: f(x)= 22.973932848862958
# differential_evolution step 576: f(x)= 22.973932848862958
# differential_evolution step 577: f(x)= 22.973932848862958
# differential_evolution step 578: f(x)= 22.973932848862958
# differential_evolution step 579: f(x)= 22.417499836543207
# differential_evolution step 580: f(x)= 22.417499836543207
# differential_evolution step 581: f(x)= 22.417499836543207
# differential_evolution step 582: f(x)= 22.417499836543207
# differential_evolution step 583: f(x)= 22.417499836543207
# differential_evolution step 584: f(x)= 22.417499836543207
# differential_evolution step 585: f(x)= 22.417499836543207
# differential_evolution step 586: f(x)= 22.417499836543207
# differential_evolution step 587: f(x)= 22.417499836543207
# differential_evolution step 588: f(x)= 22.417499836543207
# differential_evolution step 589: f(x)= 22.417499836543207
# differential_evolution step 590: f(x)= 22.417499836543207
# differential_evolution step 591: f(x)= 22.417499836543207
# differential_evolution step 592: f(x)= 22.417499836543207
# differential_evolution step 593: f(x)= 22.417499836543207
# differential_evolution step 594: f(x)= 22.417499836543207
# differential_evolution step 595: f(x)= 22.417499836543207
# differential_evolution step 596: f(x)= 22.417499836543207
# differential_evolution step 597: f(x)= 22.417499836543207
# differential_evolution step 598: f(x)= 22.417499836543207
# differential_evolution step 599: f(x)= 22.417499836543207
# differential_evolution step 600: f(x)= 22.417499836543207
# differential_evolution step 601: f(x)= 22.417499836543207
# differential_evolution step 602: f(x)= 22.417499836543207
# differential_evolution step 603: f(x)= 22.417499836543207
# differential_evolution step 604: f(x)= 22.417499836543207
# differential_evolution step 605: f(x)= 22.417499836543207
# differential_evolution step 606: f(x)= 22.417499836543207
# differential_evolution step 607: f(x)= 22.417499836543207
# differential_evolution step 608: f(x)= 22.417499836543207
# differential_evolution step 609: f(x)= 22.417499836543207
# differential_evolution step 610: f(x)= 22.417499836543207
# differential_evolution step 611: f(x)= 22.417499836543207
# differential_evolution step 612: f(x)= 22.417499836543207
# differential_evolution step 613: f(x)= 22.417499836543207
# differential_evolution step 614: f(x)= 22.417499836543207
# differential_evolution step 615: f(x)= 22.417499836543207
# differential_evolution step 616: f(x)= 22.417499836543207
# differential_evolution step 617: f(x)= 22.417499836543207
# differential_evolution step 618: f(x)= 22.417499836543207
# differential_evolution step 619: f(x)= 22.417499836543207
# differential_evolution step 620: f(x)= 22.417499836543207
# differential_evolution step 621: f(x)= 22.417499836543207
# differential_evolution step 622: f(x)= 22.417499836543207
# differential_evolution step 623: f(x)= 22.417499836543207
# differential_evolution step 624: f(x)= 22.417499836543207
# differential_evolution step 625: f(x)= 22.417499836543207
# differential_evolution step 626: f(x)= 22.417499836543207
# differential_evolution step 627: f(x)= 22.417499836543207
# differential_evolution step 628: f(x)= 22.417499836543207
# differential_evolution step 629: f(x)= 22.417499836543207
# differential_evolution step 630: f(x)= 22.417499836543207
# differential_evolution step 631: f(x)= 22.417499836543207
# differential_evolution step 632: f(x)= 22.417499836543207
# differential_evolution step 633: f(x)= 22.417499836543207
# differential_evolution step 634: f(x)= 22.107949182031287
# differential_evolution step 635: f(x)= 22.107949182031287
# differential_evolution step 636: f(x)= 22.107949182031287
# differential_evolution step 637: f(x)= 22.107949182031287
# differential_evolution step 638: f(x)= 22.107949182031287
# differential_evolution step 639: f(x)= 22.107949182031287
# differential_evolution step 640: f(x)= 22.107949182031287
# differential_evolution step 641: f(x)= 22.107949182031287
# differential_evolution step 642: f(x)= 22.107949182031287
# differential_evolution step 643: f(x)= 22.107949182031287
# differential_evolution step 644: f(x)= 22.107949182031287
# differential_evolution step 645: f(x)= 22.107949182031287
# differential_evolution step 646: f(x)= 22.107949182031287
# differential_evolution step 647: f(x)= 22.106992522836673
# differential_evolution step 648: f(x)= 22.106992522836673
# differential_evolution step 649: f(x)= 22.106992522836673
# differential_evolution step 650: f(x)= 22.106992522836673
# differential_evolution step 651: f(x)= 22.106992522836673
# differential_evolution step 652: f(x)= 22.106992522836673
# differential_evolution step 653: f(x)= 22.106992522836673
# differential_evolution step 654: f(x)= 22.106992522836673
# differential_evolution step 655: f(x)= 22.106992522836673
# differential_evolution step 656: f(x)= 22.106992522836673
# differential_evolution step 657: f(x)= 22.106992522836673
# differential_evolution step 658: f(x)= 22.106992522836673
# differential_evolution step 659: f(x)= 22.106992522836673
# differential_evolution step 660: f(x)= 22.106992522836673
# differential_evolution step 661: f(x)= 22.106992522836673
# differential_evolution step 662: f(x)= 22.106992522836673
# differential_evolution step 663: f(x)= 22.106992522836673
# differential_evolution step 664: f(x)= 22.106992522836673
# differential_evolution step 665: f(x)= 22.106992522836673
# differential_evolution step 666: f(x)= 22.106992522836673
# differential_evolution step 667: f(x)= 22.106992522836673
# differential_evolution step 668: f(x)= 22.106992522836673
# differential_evolution step 669: f(x)= 22.106992522836673
# differential_evolution step 670: f(x)= 22.106992522836673
# differential_evolution step 671: f(x)= 22.106992522836673
# differential_evolution step 672: f(x)= 22.106992522836673
# differential_evolution step 673: f(x)= 22.106992522836673
# differential_evolution step 674: f(x)= 22.106992522836673
# differential_evolution step 675: f(x)= 22.106992522836673
# differential_evolution step 676: f(x)= 22.106992522836673
# differential_evolution step 677: f(x)= 22.106992522836673
# differential_evolution step 678: f(x)= 22.106992522836673
# differential_evolution step 679: f(x)= 22.106992522836673
# differential_evolution step 680: f(x)= 22.106992522836673
# differential_evolution step 681: f(x)= 22.106992522836673
# differential_evolution step 682: f(x)= 22.04591751275691
# differential_evolution step 683: f(x)= 22.04591751275691
# differential_evolution step 684: f(x)= 22.04591751275691
# differential_evolution step 685: f(x)= 22.04591751275691
# differential_evolution step 686: f(x)= 22.04591751275691
# differential_evolution step 687: f(x)= 22.04591751275691
# differential_evolution step 688: f(x)= 22.04591751275691
# differential_evolution step 689: f(x)= 22.04591751275691
# differential_evolution step 690: f(x)= 22.04591751275691
# differential_evolution step 691: f(x)= 22.04591751275691
# differential_evolution step 692: f(x)= 21.463564341812752
# differential_evolution step 693: f(x)= 21.463564341812752
# differential_evolution step 694: f(x)= 21.463564341812752
# differential_evolution step 695: f(x)= 21.463564341812752
# differential_evolution step 696: f(x)= 21.463564341812752
# differential_evolution step 697: f(x)= 21.463564341812752
# differential_evolution step 698: f(x)= 21.463564341812752
# differential_evolution step 699: f(x)= 21.463564341812752
# differential_evolution step 700: f(x)= 21.463564341812752
# differential_evolution step 701: f(x)= 21.463564341812752
# differential_evolution step 702: f(x)= 21.463564341812752
# differential_evolution step 703: f(x)= 21.463564341812752
# differential_evolution step 704: f(x)= 21.463564341812752
# differential_evolution step 705: f(x)= 21.463564341812752
# differential_evolution step 706: f(x)= 21.463564341812752
# differential_evolution step 707: f(x)= 21.463564341812752
# differential_evolution step 708: f(x)= 21.463564341812752
# differential_evolution step 709: f(x)= 21.463564341812752
# differential_evolution step 710: f(x)= 21.463564341812752
# differential_evolution step 711: f(x)= 21.463564341812752
# differential_evolution step 712: f(x)= 21.463564341812752
# differential_evolution step 713: f(x)= 21.463564341812752
# differential_evolution step 714: f(x)= 21.463564341812752
# differential_evolution step 715: f(x)= 21.463564341812752
# differential_evolution step 716: f(x)= 21.463564341812752
# differential_evolution step 717: f(x)= 21.463564341812752
# differential_evolution step 718: f(x)= 21.463564341812752
# differential_evolution step 719: f(x)= 21.463564341812752
# differential_evolution step 720: f(x)= 21.463564341812752
# differential_evolution step 721: f(x)= 21.463564341812752
# differential_evolution step 722: f(x)= 21.463564341812752
# differential_evolution step 723: f(x)= 21.463564341812752
# differential_evolution step 724: f(x)= 21.463564341812752
# differential_evolution step 725: f(x)= 21.463564341812752
# differential_evolution step 726: f(x)= 21.463564341812752
# differential_evolution step 727: f(x)= 20.788889601417488
# differential_evolution step 728: f(x)= 20.788889601417488
# differential_evolution step 729: f(x)= 20.788889601417488
# differential_evolution step 730: f(x)= 20.788889601417488
# differential_evolution step 731: f(x)= 20.788889601417488
# differential_evolution step 732: f(x)= 20.788889601417488
# differential_evolution step 733: f(x)= 20.788889601417488
# differential_evolution step 734: f(x)= 20.788889601417488
# differential_evolution step 735: f(x)= 20.788889601417488
# differential_evolution step 736: f(x)= 20.788889601417488
# differential_evolution step 737: f(x)= 20.788889601417488
# differential_evolution step 738: f(x)= 20.788889601417488
# differential_evolution step 739: f(x)= 20.788889601417488
# differential_evolution step 740: f(x)= 20.788889601417488
# differential_evolution step 741: f(x)= 20.788889601417488
# differential_evolution step 742: f(x)= 20.788889601417488
# differential_evolution step 743: f(x)= 20.788889601417488
# differential_evolution step 744: f(x)= 20.788889601417488
# differential_evolution step 745: f(x)= 20.788889601417488
# differential_evolution step 746: f(x)= 20.788889601417488
# differential_evolution step 747: f(x)= 20.788889601417488
# differential_evolution step 748: f(x)= 20.788889601417488
# differential_evolution step 749: f(x)= 20.788889601417488
# differential_evolution step 750: f(x)= 20.788889601417488
# differential_evolution step 751: f(x)= 20.788889601417488
# differential_evolution step 752: f(x)= 20.788889601417488
# differential_evolution step 753: f(x)= 20.788889601417488
# differential_evolution step 754: f(x)= 20.788889601417488
# differential_evolution step 755: f(x)= 20.788889601417488
# differential_evolution step 756: f(x)= 20.788889601417488
# differential_evolution step 757: f(x)= 20.723891221426644
# differential_evolution step 758: f(x)= 20.723891221426644
# differential_evolution step 759: f(x)= 20.723891221426644
# differential_evolution step 760: f(x)= 20.723891221426644
# differential_evolution step 761: f(x)= 20.723891221426644
# differential_evolution step 762: f(x)= 20.723891221426644
# differential_evolution step 763: f(x)= 20.723891221426644
# differential_evolution step 764: f(x)= 20.259585790557537
# differential_evolution step 765: f(x)= 20.259585790557537
# differential_evolution step 766: f(x)= 20.259585790557537
# differential_evolution step 767: f(x)= 20.259585790557537
# differential_evolution step 768: f(x)= 20.259585790557537
# differential_evolution step 769: f(x)= 20.204383477856112
# differential_evolution step 770: f(x)= 20.204383477856112
# differential_evolution step 771: f(x)= 20.204383477856112
# differential_evolution step 772: f(x)= 20.204383477856112
# differential_evolution step 773: f(x)= 20.204383477856112
# differential_evolution step 774: f(x)= 20.204383477856112
# differential_evolution step 775: f(x)= 20.204383477856112
# differential_evolution step 776: f(x)= 20.204383477856112
# differential_evolution step 777: f(x)= 20.204383477856112
# differential_evolution step 778: f(x)= 20.204383477856112
# differential_evolution step 779: f(x)= 20.204383477856112
# differential_evolution step 780: f(x)= 20.204383477856112
# differential_evolution step 781: f(x)= 20.204383477856112
# differential_evolution step 782: f(x)= 20.204383477856112
# differential_evolution step 783: f(x)= 20.204383477856112
# differential_evolution step 784: f(x)= 20.204383477856112
# differential_evolution step 785: f(x)= 20.204383477856112
# differential_evolution step 786: f(x)= 20.204383477856112
# differential_evolution step 787: f(x)= 20.204383477856112
# differential_evolution step 788: f(x)= 20.204383477856112
# differential_evolution step 789: f(x)= 20.204383477856112
# differential_evolution step 790: f(x)= 20.204383477856112
# differential_evolution step 791: f(x)= 20.204383477856112
# differential_evolution step 792: f(x)= 20.204383477856112
# differential_evolution step 793: f(x)= 20.204383477856112
# differential_evolution step 794: f(x)= 20.204383477856112
# differential_evolution step 795: f(x)= 20.204383477856112
# differential_evolution step 796: f(x)= 20.204383477856112
# differential_evolution step 797: f(x)= 20.204383477856112
# differential_evolution step 798: f(x)= 20.204383477856112
# differential_evolution step 799: f(x)= 20.204383477856112
# differential_evolution step 800: f(x)= 20.204383477856112
# differential_evolution step 801: f(x)= 20.204383477856112
# differential_evolution step 802: f(x)= 20.204383477856112
# differential_evolution step 803: f(x)= 20.204383477856112
# differential_evolution step 804: f(x)= 20.204383477856112
# differential_evolution step 805: f(x)= 20.204383477856112
# differential_evolution step 806: f(x)= 19.83806110888308
# differential_evolution step 807: f(x)= 19.83806110888308
# differential_evolution step 808: f(x)= 19.83806110888308
# differential_evolution step 809: f(x)= 19.83806110888308
# differential_evolution step 810: f(x)= 19.83806110888308
# differential_evolution step 811: f(x)= 19.83806110888308
# differential_evolution step 812: f(x)= 19.83806110888308
# differential_evolution step 813: f(x)= 19.83806110888308
# differential_evolution step 814: f(x)= 19.83806110888308
# differential_evolution step 815: f(x)= 19.475831102193307
# differential_evolution step 816: f(x)= 19.475831102193307
# differential_evolution step 817: f(x)= 19.475831102193307
# differential_evolution step 818: f(x)= 19.475831102193307
# differential_evolution step 819: f(x)= 19.475831102193307
# differential_evolution step 820: f(x)= 19.475831102193307
# differential_evolution step 821: f(x)= 19.475831102193307
# differential_evolution step 822: f(x)= 19.475831102193307
# differential_evolution step 823: f(x)= 19.475831102193307
# differential_evolution step 824: f(x)= 19.475831102193307
# differential_evolution step 825: f(x)= 19.475831102193307
# differential_evolution step 826: f(x)= 19.475831102193307
# differential_evolution step 827: f(x)= 19.475831102193307
# differential_evolution step 828: f(x)= 19.475831102193307
# differential_evolution step 829: f(x)= 18.70428414221946
# differential_evolution step 830: f(x)= 18.70428414221946
# differential_evolution step 831: f(x)= 18.70428414221946
# differential_evolution step 832: f(x)= 18.70428414221946
# differential_evolution step 833: f(x)= 18.70428414221946
# differential_evolution step 834: f(x)= 18.70428414221946
# differential_evolution step 835: f(x)= 18.70428414221946
# differential_evolution step 836: f(x)= 18.70428414221946
# differential_evolution step 837: f(x)= 18.70428414221946
# differential_evolution step 838: f(x)= 18.70428414221946
# differential_evolution step 839: f(x)= 18.70428414221946
# differential_evolution step 840: f(x)= 18.70428414221946
# differential_evolution step 841: f(x)= 18.70428414221946
# differential_evolution step 842: f(x)= 18.70428414221946
# differential_evolution step 843: f(x)= 18.70428414221946
# differential_evolution step 844: f(x)= 18.70428414221946
# differential_evolution step 845: f(x)= 18.70428414221946
# differential_evolution step 846: f(x)= 18.70428414221946
# differential_evolution step 847: f(x)= 18.70428414221946
# differential_evolution step 848: f(x)= 18.70428414221946
# differential_evolution step 849: f(x)= 18.70428414221946
# differential_evolution step 850: f(x)= 18.70428414221946
# differential_evolution step 851: f(x)= 18.70428414221946
# differential_evolution step 852: f(x)= 18.70428414221946
# differential_evolution step 853: f(x)= 18.70428414221946
# differential_evolution step 854: f(x)= 18.70428414221946
# differential_evolution step 855: f(x)= 18.70428414221946
# differential_evolution step 856: f(x)= 18.70428414221946
# differential_evolution step 857: f(x)= 18.70428414221946
# differential_evolution step 858: f(x)= 18.70428414221946
# differential_evolution step 859: f(x)= 18.70428414221946
# differential_evolution step 860: f(x)= 18.70428414221946
# differential_evolution step 861: f(x)= 18.70428414221946
# differential_evolution step 862: f(x)= 18.70428414221946
# differential_evolution step 863: f(x)= 18.70428414221946
# differential_evolution step 864: f(x)= 18.70428414221946
# differential_evolution step 865: f(x)= 18.70428414221946
# differential_evolution step 866: f(x)= 18.70428414221946
# differential_evolution step 867: f(x)= 18.70428414221946
# differential_evolution step 868: f(x)= 18.70428414221946
# differential_evolution step 869: f(x)= 18.70428414221946
# differential_evolution step 870: f(x)= 18.70428414221946
# differential_evolution step 871: f(x)= 18.70428414221946
# differential_evolution step 872: f(x)= 18.70428414221946
# differential_evolution step 873: f(x)= 18.70428414221946
# differential_evolution step 874: f(x)= 18.70428414221946
# differential_evolution step 875: f(x)= 18.70428414221946
# differential_evolution step 876: f(x)= 18.70428414221946
# differential_evolution step 877: f(x)= 18.70428414221946
# differential_evolution step 878: f(x)= 18.70428414221946
# differential_evolution step 879: f(x)= 18.70428414221946
# differential_evolution step 880: f(x)= 18.70428414221946
# differential_evolution step 881: f(x)= 18.70428414221946
# differential_evolution step 882: f(x)= 18.70428414221946
# differential_evolution step 883: f(x)= 18.332778627986023
# differential_evolution step 884: f(x)= 18.332778627986023
# differential_evolution step 885: f(x)= 18.332778627986023
# differential_evolution step 886: f(x)= 18.332778627986023
# differential_evolution step 887: f(x)= 18.332778627986023
# differential_evolution step 888: f(x)= 18.332778627986023
# differential_evolution step 889: f(x)= 18.332778627986023
# differential_evolution step 890: f(x)= 18.332778627986023
# differential_evolution step 891: f(x)= 18.332778627986023
# differential_evolution step 892: f(x)= 18.332778627986023
# differential_evolution step 893: f(x)= 18.332778627986023
# differential_evolution step 894: f(x)= 18.332778627986023
# differential_evolution step 895: f(x)= 18.332778627986023
# differential_evolution step 896: f(x)= 18.332778627986023
# differential_evolution step 897: f(x)= 18.332778627986023
# differential_evolution step 898: f(x)= 18.332778627986023
# differential_evolution step 899: f(x)= 18.332778627986023
# differential_evolution step 900: f(x)= 18.151167230158727
# differential_evolution step 901: f(x)= 18.151167230158727
# differential_evolution step 902: f(x)= 18.151167230158727
# differential_evolution step 903: f(x)= 18.151167230158727
# differential_evolution step 904: f(x)= 18.151167230158727
# differential_evolution step 905: f(x)= 18.151167230158727
# differential_evolution step 906: f(x)= 18.151167230158727
# differential_evolution step 907: f(x)= 18.151167230158727
# differential_evolution step 908: f(x)= 18.151167230158727
# differential_evolution step 909: f(x)= 18.151167230158727
# differential_evolution step 910: f(x)= 17.969984884968458
# differential_evolution step 911: f(x)= 17.969984884968458
# differential_evolution step 912: f(x)= 17.969984884968458
# differential_evolution step 913: f(x)= 17.969984884968458
# differential_evolution step 914: f(x)= 17.969984884968458
# differential_evolution step 915: f(x)= 17.969984884968458
# differential_evolution step 916: f(x)= 17.969984884968458
# differential_evolution step 917: f(x)= 17.969984884968458
# differential_evolution step 918: f(x)= 17.969984884968458
# differential_evolution step 919: f(x)= 17.969984884968458
# differential_evolution step 920: f(x)= 17.969984884968458
# differential_evolution step 921: f(x)= 17.969984884968458
# differential_evolution step 922: f(x)= 17.969984884968458
# differential_evolution step 923: f(x)= 17.969984884968458
# differential_evolution step 924: f(x)= 17.969984884968458
# differential_evolution step 925: f(x)= 17.969984884968458
# differential_evolution step 926: f(x)= 17.969984884968458
# differential_evolution step 927: f(x)= 17.969984884968458
# differential_evolution step 928: f(x)= 17.969984884968458
# differential_evolution step 929: f(x)= 17.969984884968458
# differential_evolution step 930: f(x)= 17.969984884968458
# differential_evolution step 931: f(x)= 17.969984884968458
# differential_evolution step 932: f(x)= 17.640392299815538
# differential_evolution step 933: f(x)= 17.640392299815538
# differential_evolution step 934: f(x)= 17.640392299815538
# differential_evolution step 935: f(x)= 17.640392299815538
# differential_evolution step 936: f(x)= 17.640392299815538
# differential_evolution step 937: f(x)= 17.640392299815538
# differential_evolution step 938: f(x)= 17.640392299815538
# differential_evolution step 939: f(x)= 17.640392299815538
# differential_evolution step 940: f(x)= 17.640392299815538
# differential_evolution step 941: f(x)= 17.640392299815538
# differential_evolution step 942: f(x)= 17.640392299815538
# differential_evolution step 943: f(x)= 17.640392299815538
# differential_evolution step 944: f(x)= 17.640392299815538
# differential_evolution step 945: f(x)= 17.640392299815538
# differential_evolution step 946: f(x)= 17.640392299815538
# differential_evolution step 947: f(x)= 17.640392299815538
# differential_evolution step 948: f(x)= 17.640392299815538
# differential_evolution step 949: f(x)= 17.640392299815538
# differential_evolution step 950: f(x)= 17.640392299815538
# differential_evolution step 951: f(x)= 17.640392299815538
# differential_evolution step 952: f(x)= 17.640392299815538
# differential_evolution step 953: f(x)= 17.640392299815538
# differential_evolution step 954: f(x)= 17.640392299815538
# differential_evolution step 955: f(x)= 17.640392299815538
# differential_evolution step 956: f(x)= 17.640392299815538
# differential_evolution step 957: f(x)= 17.640392299815538
# differential_evolution step 958: f(x)= 17.640392299815538
# differential_evolution step 959: f(x)= 17.640392299815538
# differential_evolution step 960: f(x)= 17.640392299815538
# differential_evolution step 961: f(x)= 17.45471151188029
# differential_evolution step 962: f(x)= 17.45471151188029
# differential_evolution step 963: f(x)= 17.45471151188029
# differential_evolution step 964: f(x)= 17.45471151188029
# differential_evolution step 965: f(x)= 17.45471151188029
# differential_evolution step 966: f(x)= 17.45471151188029
# differential_evolution step 967: f(x)= 17.45471151188029
# differential_evolution step 968: f(x)= 17.45471151188029
# differential_evolution step 969: f(x)= 17.45471151188029
# differential_evolution step 970: f(x)= 17.45471151188029
# differential_evolution step 971: f(x)= 17.45471151188029
# differential_evolution step 972: f(x)= 17.45471151188029
# differential_evolution step 973: f(x)= 17.45471151188029
# differential_evolution step 974: f(x)= 17.45471151188029
# differential_evolution step 975: f(x)= 17.45471151188029
# differential_evolution step 976: f(x)= 17.45471151188029
# differential_evolution step 977: f(x)= 17.45471151188029
# differential_evolution step 978: f(x)= 17.45471151188029
# differential_evolution step 979: f(x)= 17.45471151188029
# differential_evolution step 980: f(x)= 17.45471151188029
# differential_evolution step 981: f(x)= 17.45471151188029
# differential_evolution step 982: f(x)= 17.45471151188029
# differential_evolution step 983: f(x)= 17.313480407123187
# differential_evolution step 984: f(x)= 17.313480407123187
# differential_evolution step 985: f(x)= 17.313480407123187
# differential_evolution step 986: f(x)= 17.313480407123187
# differential_evolution step 987: f(x)= 17.313480407123187
# differential_evolution step 988: f(x)= 17.313480407123187
# differential_evolution step 989: f(x)= 17.313480407123187
# differential_evolution step 990: f(x)= 17.313480407123187
# differential_evolution step 991: f(x)= 17.313480407123187
# differential_evolution step 992: f(x)= 17.313480407123187
# differential_evolution step 993: f(x)= 17.313480407123187
# differential_evolution step 994: f(x)= 17.18648710350766
# differential_evolution step 995: f(x)= 17.18648710350766
# differential_evolution step 996: f(x)= 17.18648710350766
# differential_evolution step 997: f(x)= 17.18648710350766
# differential_evolution step 998: f(x)= 17.18648710350766
# differential_evolution step 999: f(x)= 17.18648710350766
# differential_evolution step 1000: f(x)= 17.18648710350766
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.6837, r_e=8.7552, n=1.8197, x_0=16.7160
# Sérsic 2: I_e=5.0102, r_e=2.7000, n=2.6618, x_0=41.6037
# Sérsic 3: I_e=1.7455, r_e=17.2549, n=1.6120, x_0=65.9679
# Sérsic 4: I_e=5.1743, r_e=5.8871, n=0.3745, x_0=62.5966
# Sérsic 5: I_e=1.3694, r_e=3.8970, n=1.7890, x_0=72.5528
# Sérsic 6: I_e=0.0998, r_e=4.7735, n=2.2064, x_0=91.2237
# Chi quadro minimo: 17.18648710350766
# False

# %%
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Sérsic 1: I_e=0.6837, r_e=8.7552, n=1.8197, x_0=16.7160
# Sérsic 2: I_e=5.0102, r_e=2.7000, n=2.6618, x_0=41.6037
# Sérsic 3: I_e=1.7455, r_e=17.2549, n=1.6120, x_0=65.9679
# Sérsic 4: I_e=5.1743, r_e=5.8871, n=0.3745, x_0=62.5966
# Sérsic 5: I_e=1.3694, r_e=3.8970, n=1.7890, x_0=72.5528
# Sérsic 6: I_e=0.0998, r_e=4.7735, n=2.2064, x_0=91.2237
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = real_errors_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4450, r_e=10.0000, n=2.1639, x_0=16.5866
# Sérsic 2: I_e=3.1424, r_e=3.2557, n=3.2747, x_0=41.5762
# Sérsic 3: I_e=0.3384, r_e=49.9999, n=2.5835, x_0=65.9756
# Sérsic 4: I_e=6.4279, r_e=6.3652, n=0.4539, x_0=63.4700
# Sérsic 5: I_e=2.6550, r_e=2.8253, n=1.2208, x_0=72.5673
# Sérsic 6: I_e=0.1000, r_e=5.0000, n=1.8697, x_0=91.1830
# [6.60504731e-01 1.10277723e+01 1.45238449e+00 1.23457951e-02
#  2.21459934e+00 1.35911134e+00 7.30181945e-01 2.30434740e-02
#  6.03277620e-01 6.76860624e+01 1.26566474e+00 2.23830120e-01
#  1.26453356e+00 6.53484976e-01 6.20045485e-02 1.34843163e+00
#  1.69461043e+00 9.30722698e-01 4.79626666e-01 1.86913030e-01
#  6.37539014e-01 2.65825190e+01 4.64645942e+00 3.09713096e-01]
# 1.2495966182940748

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5400\3111683727.py:43: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))
real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[2])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 30461.869883062987
# differential_evolution step 2: f(x)= 13182.427327614425
# differential_evolution step 3: f(x)= 7890.0848621186815
# differential_evolution step 4: f(x)= 1936.989851549805
# differential_evolution step 5: f(x)= 1936.989851549805
# differential_evolution step 6: f(x)= 1936.989851549805
# differential_evolution step 7: f(x)= 1936.989851549805
# differential_evolution step 8: f(x)= 1936.989851549805
# differential_evolution step 9: f(x)= 1936.989851549805
# differential_evolution step 10: f(x)= 792.1019966494073
# differential_evolution step 11: f(x)= 792.1019966494073
# differential_evolution step 12: f(x)= 792.1019966494073
# differential_evolution step 13: f(x)= 792.1019966494073
# differential_evolution step 14: f(x)= 792.1019966494073
# differential_evolution step 15: f(x)= 668.1448105798822
# differential_evolution step 16: f(x)= 538.6604570379594
# differential_evolution step 17: f(x)= 538.6604570379594
# differential_evolution step 18: f(x)= 538.6604570379594
# differential_evolution step 19: f(x)= 538.6604570379594
# differential_evolution step 20: f(x)= 538.6604570379594
# differential_evolution step 21: f(x)= 538.6604570379594
# differential_evolution step 22: f(x)= 336.3759807765149
# differential_evolution step 23: f(x)= 336.3759807765149
# differential_evolution step 24: f(x)= 336.3759807765149
# differential_evolution step 25: f(x)= 336.3759807765149
# differential_evolution step 26: f(x)= 336.3759807765149
# differential_evolution step 27: f(x)= 336.3759807765149
# differential_evolution step 28: f(x)= 336.3759807765149
# differential_evolution step 29: f(x)= 336.3759807765149
# differential_evolution step 30: f(x)= 336.3759807765149
# differential_evolution step 31: f(x)= 336.3759807765149
# differential_evolution step 32: f(x)= 336.3759807765149
# differential_evolution step 33: f(x)= 336.3759807765149
# differential_evolution step 34: f(x)= 336.3759807765149
# differential_evolution step 35: f(x)= 336.3759807765149
# differential_evolution step 36: f(x)= 336.3759807765149
# differential_evolution step 37: f(x)= 336.3759807765149
# differential_evolution step 38: f(x)= 336.3759807765149
# differential_evolution step 39: f(x)= 336.3759807765149
# differential_evolution step 40: f(x)= 336.3759807765149
# differential_evolution step 41: f(x)= 336.3759807765149
# differential_evolution step 42: f(x)= 336.3759807765149
# differential_evolution step 43: f(x)= 336.3759807765149
# differential_evolution step 44: f(x)= 300.1612815797597
# differential_evolution step 45: f(x)= 300.1612815797597
# differential_evolution step 46: f(x)= 300.1612815797597
# differential_evolution step 47: f(x)= 300.1612815797597
# differential_evolution step 48: f(x)= 300.1612815797597
# differential_evolution step 49: f(x)= 200.5149193540621
# differential_evolution step 50: f(x)= 200.5149193540621
# differential_evolution step 51: f(x)= 200.5149193540621
# differential_evolution step 52: f(x)= 200.5149193540621
# differential_evolution step 53: f(x)= 200.5149193540621
# differential_evolution step 54: f(x)= 200.5149193540621
# differential_evolution step 55: f(x)= 195.06402832233775
# differential_evolution step 56: f(x)= 195.06402832233775
# differential_evolution step 57: f(x)= 195.06402832233775
# differential_evolution step 58: f(x)= 195.06402832233775
# differential_evolution step 59: f(x)= 195.06402832233775
# differential_evolution step 60: f(x)= 195.06402832233775
# differential_evolution step 61: f(x)= 195.06402832233775
# differential_evolution step 62: f(x)= 195.06402832233775
# differential_evolution step 63: f(x)= 195.06402832233775
# differential_evolution step 64: f(x)= 168.7668092706747
# differential_evolution step 65: f(x)= 168.7668092706747
# differential_evolution step 66: f(x)= 161.6068539670497
# differential_evolution step 67: f(x)= 161.6068539670497
# differential_evolution step 68: f(x)= 161.6068539670497
# differential_evolution step 69: f(x)= 161.6068539670497
# differential_evolution step 70: f(x)= 161.6068539670497
# differential_evolution step 71: f(x)= 147.1457935701326
# differential_evolution step 72: f(x)= 147.1457935701326
# differential_evolution step 73: f(x)= 147.1457935701326
# differential_evolution step 74: f(x)= 147.1457935701326
# differential_evolution step 75: f(x)= 147.1457935701326
# differential_evolution step 76: f(x)= 147.1457935701326
# differential_evolution step 77: f(x)= 147.1457935701326
# differential_evolution step 78: f(x)= 147.1457935701326
# differential_evolution step 79: f(x)= 147.1457935701326
# differential_evolution step 80: f(x)= 147.1457935701326
# differential_evolution step 81: f(x)= 147.1457935701326
# differential_evolution step 82: f(x)= 147.1457935701326
# differential_evolution step 83: f(x)= 147.1457935701326
# differential_evolution step 84: f(x)= 147.1457935701326
# differential_evolution step 85: f(x)= 114.72313165651273
# differential_evolution step 86: f(x)= 110.71296828540254
# differential_evolution step 87: f(x)= 110.71296828540254
# differential_evolution step 88: f(x)= 110.71296828540254
# differential_evolution step 89: f(x)= 110.71296828540254
# differential_evolution step 90: f(x)= 92.3655862159822
# differential_evolution step 91: f(x)= 78.55326247792615
# differential_evolution step 92: f(x)= 78.55326247792615
# differential_evolution step 93: f(x)= 78.55326247792615
# differential_evolution step 94: f(x)= 78.55326247792615
# differential_evolution step 95: f(x)= 78.55326247792615
# differential_evolution step 96: f(x)= 78.55326247792615
# differential_evolution step 97: f(x)= 78.55326247792615
# differential_evolution step 98: f(x)= 78.55326247792615
# differential_evolution step 99: f(x)= 78.55326247792615
# differential_evolution step 100: f(x)= 78.55326247792615
# differential_evolution step 101: f(x)= 78.55326247792615
# differential_evolution step 102: f(x)= 78.55326247792615
# differential_evolution step 103: f(x)= 78.55326247792615
# differential_evolution step 104: f(x)= 78.55326247792615
# differential_evolution step 105: f(x)= 78.55326247792615
# differential_evolution step 106: f(x)= 78.55326247792615
# differential_evolution step 107: f(x)= 78.55326247792615
# differential_evolution step 108: f(x)= 78.55326247792615
# differential_evolution step 109: f(x)= 78.55326247792615
# differential_evolution step 110: f(x)= 78.55326247792615
# differential_evolution step 111: f(x)= 78.55326247792615
# differential_evolution step 112: f(x)= 78.55326247792615
# differential_evolution step 113: f(x)= 78.55326247792615
# differential_evolution step 114: f(x)= 78.55326247792615
# differential_evolution step 115: f(x)= 77.05217464752947
# differential_evolution step 116: f(x)= 75.7721034125332
# differential_evolution step 117: f(x)= 75.7721034125332
# differential_evolution step 118: f(x)= 75.7721034125332
# differential_evolution step 119: f(x)= 58.168225558032276
# differential_evolution step 120: f(x)= 58.168225558032276
# differential_evolution step 121: f(x)= 58.168225558032276
# differential_evolution step 122: f(x)= 58.168225558032276
# differential_evolution step 123: f(x)= 58.168225558032276
# differential_evolution step 124: f(x)= 58.168225558032276
# differential_evolution step 125: f(x)= 58.168225558032276
# differential_evolution step 126: f(x)= 58.168225558032276
# differential_evolution step 127: f(x)= 58.168225558032276
# differential_evolution step 128: f(x)= 58.168225558032276
# differential_evolution step 129: f(x)= 58.168225558032276
# differential_evolution step 130: f(x)= 54.689180569343094
# differential_evolution step 131: f(x)= 54.689180569343094
# differential_evolution step 132: f(x)= 54.689180569343094
# differential_evolution step 133: f(x)= 54.689180569343094
# differential_evolution step 134: f(x)= 54.689180569343094
# differential_evolution step 135: f(x)= 54.689180569343094
# differential_evolution step 136: f(x)= 54.689180569343094
# differential_evolution step 137: f(x)= 54.689180569343094
# differential_evolution step 138: f(x)= 51.853642485012195
# differential_evolution step 139: f(x)= 51.853642485012195
# differential_evolution step 140: f(x)= 51.853642485012195
# differential_evolution step 141: f(x)= 51.853642485012195
# differential_evolution step 142: f(x)= 51.853642485012195
# differential_evolution step 143: f(x)= 51.853642485012195
# differential_evolution step 144: f(x)= 51.853642485012195
# differential_evolution step 145: f(x)= 51.853642485012195
# differential_evolution step 146: f(x)= 51.853642485012195
# differential_evolution step 147: f(x)= 51.853642485012195
# differential_evolution step 148: f(x)= 51.853642485012195
# differential_evolution step 149: f(x)= 51.853642485012195
# differential_evolution step 150: f(x)= 51.853642485012195
# differential_evolution step 151: f(x)= 46.146702893359546
# differential_evolution step 152: f(x)= 46.146702893359546
# differential_evolution step 153: f(x)= 46.146702893359546
# differential_evolution step 154: f(x)= 46.146702893359546
# differential_evolution step 155: f(x)= 46.146702893359546
# differential_evolution step 156: f(x)= 46.146702893359546
# differential_evolution step 157: f(x)= 46.146702893359546
# differential_evolution step 158: f(x)= 46.146702893359546
# differential_evolution step 159: f(x)= 46.06917937322619
# differential_evolution step 160: f(x)= 46.06917937322619
# differential_evolution step 161: f(x)= 46.06917937322619
# differential_evolution step 162: f(x)= 46.06917937322619
# differential_evolution step 163: f(x)= 46.06917937322619
# differential_evolution step 164: f(x)= 46.06917937322619
# differential_evolution step 165: f(x)= 43.74586470340783
# differential_evolution step 166: f(x)= 43.74586470340783
# differential_evolution step 167: f(x)= 43.74586470340783
# differential_evolution step 168: f(x)= 43.74586470340783
# differential_evolution step 169: f(x)= 43.74586470340783
# differential_evolution step 170: f(x)= 43.74586470340783
# differential_evolution step 171: f(x)= 43.74586470340783
# differential_evolution step 172: f(x)= 43.74586470340783
# differential_evolution step 173: f(x)= 43.74586470340783
# differential_evolution step 174: f(x)= 43.74586470340783
# differential_evolution step 175: f(x)= 43.74586470340783
# differential_evolution step 176: f(x)= 43.74586470340783
# differential_evolution step 177: f(x)= 43.74586470340783
# differential_evolution step 178: f(x)= 43.74586470340783
# differential_evolution step 179: f(x)= 43.74586470340783
# differential_evolution step 180: f(x)= 43.74586470340783
# differential_evolution step 181: f(x)= 43.74586470340783
# differential_evolution step 182: f(x)= 43.74586470340783
# differential_evolution step 183: f(x)= 43.74586470340783
# differential_evolution step 184: f(x)= 43.74586470340783
# differential_evolution step 185: f(x)= 43.74586470340783
# differential_evolution step 186: f(x)= 43.74586470340783
# differential_evolution step 187: f(x)= 43.74586470340783
# differential_evolution step 188: f(x)= 43.74586470340783
# differential_evolution step 189: f(x)= 43.74586470340783
# differential_evolution step 190: f(x)= 43.74586470340783
# differential_evolution step 191: f(x)= 43.74586470340783
# differential_evolution step 192: f(x)= 43.74586470340783
# differential_evolution step 193: f(x)= 43.74586470340783
# differential_evolution step 194: f(x)= 43.74586470340783
# differential_evolution step 195: f(x)= 43.74586470340783
# differential_evolution step 196: f(x)= 43.74586470340783
# differential_evolution step 197: f(x)= 43.74586470340783
# differential_evolution step 198: f(x)= 43.74586470340783
# differential_evolution step 199: f(x)= 43.74586470340783
# differential_evolution step 200: f(x)= 43.74586470340783
# differential_evolution step 201: f(x)= 43.74586470340783
# differential_evolution step 202: f(x)= 43.74586470340783
# differential_evolution step 203: f(x)= 43.74586470340783
# differential_evolution step 204: f(x)= 41.23217458335096
# differential_evolution step 205: f(x)= 40.113240331910745
# differential_evolution step 206: f(x)= 40.113240331910745
# differential_evolution step 207: f(x)= 37.84993514709648
# differential_evolution step 208: f(x)= 37.84993514709648
# differential_evolution step 209: f(x)= 37.84993514709648
# differential_evolution step 210: f(x)= 37.84993514709648
# differential_evolution step 211: f(x)= 37.84993514709648
# differential_evolution step 212: f(x)= 37.84993514709648
# differential_evolution step 213: f(x)= 37.84993514709648
# differential_evolution step 214: f(x)= 37.84993514709648
# differential_evolution step 215: f(x)= 35.99101071374892
# differential_evolution step 216: f(x)= 35.99101071374892
# differential_evolution step 217: f(x)= 35.99101071374892
# differential_evolution step 218: f(x)= 35.99101071374892
# differential_evolution step 219: f(x)= 35.99101071374892
# differential_evolution step 220: f(x)= 35.99101071374892
# differential_evolution step 221: f(x)= 35.99101071374892
# differential_evolution step 222: f(x)= 35.99101071374892
# differential_evolution step 223: f(x)= 35.99101071374892
# differential_evolution step 224: f(x)= 35.99101071374892
# differential_evolution step 225: f(x)= 35.99101071374892
# differential_evolution step 226: f(x)= 35.99101071374892
# differential_evolution step 227: f(x)= 35.99101071374892
# differential_evolution step 228: f(x)= 35.99101071374892
# differential_evolution step 229: f(x)= 35.99101071374892
# differential_evolution step 230: f(x)= 35.99101071374892
# differential_evolution step 231: f(x)= 35.99101071374892
# differential_evolution step 232: f(x)= 35.99101071374892
# differential_evolution step 233: f(x)= 35.99101071374892
# differential_evolution step 234: f(x)= 35.99101071374892
# differential_evolution step 235: f(x)= 35.99101071374892
# differential_evolution step 236: f(x)= 35.99101071374892
# differential_evolution step 237: f(x)= 35.99101071374892
# differential_evolution step 238: f(x)= 35.99101071374892
# differential_evolution step 239: f(x)= 34.90162786071637
# differential_evolution step 240: f(x)= 34.90162786071637
# differential_evolution step 241: f(x)= 34.90162786071637
# differential_evolution step 242: f(x)= 34.90162786071637
# differential_evolution step 243: f(x)= 34.90162786071637
# differential_evolution step 244: f(x)= 34.90162786071637
# differential_evolution step 245: f(x)= 34.90162786071637
# differential_evolution step 246: f(x)= 34.90162786071637
# differential_evolution step 247: f(x)= 34.90162786071637
# differential_evolution step 248: f(x)= 34.90162786071637
# differential_evolution step 249: f(x)= 34.90162786071637
# differential_evolution step 250: f(x)= 34.90162786071637
# differential_evolution step 251: f(x)= 34.90162786071637
# differential_evolution step 252: f(x)= 34.90162786071637
# differential_evolution step 253: f(x)= 34.90162786071637
# differential_evolution step 254: f(x)= 34.90162786071637
# differential_evolution step 255: f(x)= 34.90162786071637
# differential_evolution step 256: f(x)= 33.193746037998494
# differential_evolution step 257: f(x)= 33.193746037998494
# differential_evolution step 258: f(x)= 33.193746037998494
# differential_evolution step 259: f(x)= 33.193746037998494
# differential_evolution step 260: f(x)= 33.193746037998494
# differential_evolution step 261: f(x)= 33.193746037998494
# differential_evolution step 262: f(x)= 33.193746037998494
# differential_evolution step 263: f(x)= 33.193746037998494
# differential_evolution step 264: f(x)= 33.193746037998494
# differential_evolution step 265: f(x)= 33.193746037998494
# differential_evolution step 266: f(x)= 33.193746037998494
# differential_evolution step 267: f(x)= 33.193746037998494
# differential_evolution step 268: f(x)= 33.193746037998494
# differential_evolution step 269: f(x)= 33.193746037998494
# differential_evolution step 270: f(x)= 33.193746037998494
# differential_evolution step 271: f(x)= 33.193746037998494
# differential_evolution step 272: f(x)= 33.193746037998494
# differential_evolution step 273: f(x)= 33.193746037998494
# differential_evolution step 274: f(x)= 33.193746037998494
# differential_evolution step 275: f(x)= 33.193746037998494
# differential_evolution step 276: f(x)= 33.193746037998494
# differential_evolution step 277: f(x)= 33.193746037998494
# differential_evolution step 278: f(x)= 33.193746037998494
# differential_evolution step 279: f(x)= 33.193746037998494
# differential_evolution step 280: f(x)= 33.193746037998494
# differential_evolution step 281: f(x)= 33.193746037998494
# differential_evolution step 282: f(x)= 33.193746037998494
# differential_evolution step 283: f(x)= 33.193746037998494
# differential_evolution step 284: f(x)= 33.193746037998494
# differential_evolution step 285: f(x)= 33.193746037998494
# differential_evolution step 286: f(x)= 33.193746037998494
# differential_evolution step 287: f(x)= 33.193746037998494
# differential_evolution step 288: f(x)= 33.193746037998494
# differential_evolution step 289: f(x)= 33.193746037998494
# differential_evolution step 290: f(x)= 33.193746037998494
# differential_evolution step 291: f(x)= 33.193746037998494
# differential_evolution step 292: f(x)= 33.193746037998494
# differential_evolution step 293: f(x)= 32.18056237727548
# differential_evolution step 294: f(x)= 32.18056237727548
# differential_evolution step 295: f(x)= 32.18056237727548
# differential_evolution step 296: f(x)= 32.18056237727548
# differential_evolution step 297: f(x)= 31.778281456742498
# differential_evolution step 298: f(x)= 31.778281456742498
# differential_evolution step 299: f(x)= 31.778281456742498
# differential_evolution step 300: f(x)= 31.778281456742498
# differential_evolution step 301: f(x)= 31.778281456742498
# differential_evolution step 302: f(x)= 31.778281456742498
# differential_evolution step 303: f(x)= 31.778281456742498
# differential_evolution step 304: f(x)= 31.778281456742498
# differential_evolution step 305: f(x)= 31.778281456742498
# differential_evolution step 306: f(x)= 31.778281456742498
# differential_evolution step 307: f(x)= 31.778281456742498
# differential_evolution step 308: f(x)= 31.778281456742498
# differential_evolution step 309: f(x)= 31.770406448291403
# differential_evolution step 310: f(x)= 31.18123524637931
# differential_evolution step 311: f(x)= 30.91493704024165
# differential_evolution step 312: f(x)= 30.91493704024165
# differential_evolution step 313: f(x)= 30.91493704024165
# differential_evolution step 314: f(x)= 30.44651413938586
# differential_evolution step 315: f(x)= 28.676787459048597
# differential_evolution step 316: f(x)= 28.676787459048597
# differential_evolution step 317: f(x)= 28.676787459048597
# differential_evolution step 318: f(x)= 28.676787459048597
# differential_evolution step 319: f(x)= 28.676787459048597
# differential_evolution step 320: f(x)= 28.676787459048597
# differential_evolution step 321: f(x)= 28.676787459048597
# differential_evolution step 322: f(x)= 28.676787459048597
# differential_evolution step 323: f(x)= 28.676787459048597
# differential_evolution step 324: f(x)= 28.676787459048597
# differential_evolution step 325: f(x)= 28.676787459048597
# differential_evolution step 326: f(x)= 28.676787459048597
# differential_evolution step 327: f(x)= 28.676787459048597
# differential_evolution step 328: f(x)= 28.676787459048597
# differential_evolution step 329: f(x)= 28.676787459048597
# differential_evolution step 330: f(x)= 28.676787459048597
# differential_evolution step 331: f(x)= 28.676787459048597
# differential_evolution step 332: f(x)= 28.676787459048597
# differential_evolution step 333: f(x)= 28.676787459048597
# differential_evolution step 334: f(x)= 28.676787459048597
# differential_evolution step 335: f(x)= 28.676787459048597
# differential_evolution step 336: f(x)= 28.676787459048597
# differential_evolution step 337: f(x)= 28.39326785858281
# differential_evolution step 338: f(x)= 28.39326785858281
# differential_evolution step 339: f(x)= 28.39326785858281
# differential_evolution step 340: f(x)= 28.39326785858281
# differential_evolution step 341: f(x)= 28.39326785858281
# differential_evolution step 342: f(x)= 27.71248405161777
# differential_evolution step 343: f(x)= 27.71248405161777
# differential_evolution step 344: f(x)= 27.71248405161777
# differential_evolution step 345: f(x)= 27.71248405161777
# differential_evolution step 346: f(x)= 27.71248405161777
# differential_evolution step 347: f(x)= 27.71248405161777
# differential_evolution step 348: f(x)= 27.71248405161777
# differential_evolution step 349: f(x)= 27.71248405161777
# differential_evolution step 350: f(x)= 27.71248405161777
# differential_evolution step 351: f(x)= 27.71248405161777
# differential_evolution step 352: f(x)= 27.71248405161777
# differential_evolution step 353: f(x)= 27.71248405161777
# differential_evolution step 354: f(x)= 27.71248405161777
# differential_evolution step 355: f(x)= 27.71248405161777
# differential_evolution step 356: f(x)= 27.71248405161777
# differential_evolution step 357: f(x)= 27.189790628490922
# differential_evolution step 358: f(x)= 27.189790628490922
# differential_evolution step 359: f(x)= 27.189790628490922
# differential_evolution step 360: f(x)= 27.189790628490922
# differential_evolution step 361: f(x)= 27.189790628490922
# differential_evolution step 362: f(x)= 27.189790628490922
# differential_evolution step 363: f(x)= 27.189790628490922
# differential_evolution step 364: f(x)= 27.189790628490922
# differential_evolution step 365: f(x)= 27.189790628490922
# differential_evolution step 366: f(x)= 27.189790628490922
# differential_evolution step 367: f(x)= 27.189790628490922
# differential_evolution step 368: f(x)= 27.189790628490922
# differential_evolution step 369: f(x)= 27.000059158219514
# differential_evolution step 370: f(x)= 27.000059158219514
# differential_evolution step 371: f(x)= 27.000059158219514
# differential_evolution step 372: f(x)= 27.000059158219514
# differential_evolution step 373: f(x)= 27.000059158219514
# differential_evolution step 374: f(x)= 27.000059158219514
# differential_evolution step 375: f(x)= 27.000059158219514
# differential_evolution step 376: f(x)= 27.000059158219514
# differential_evolution step 377: f(x)= 27.000059158219514
# differential_evolution step 378: f(x)= 27.000059158219514
# differential_evolution step 379: f(x)= 27.000059158219514
# differential_evolution step 380: f(x)= 27.000059158219514
# differential_evolution step 381: f(x)= 27.000059158219514
# differential_evolution step 382: f(x)= 27.000059158219514
# differential_evolution step 383: f(x)= 27.000059158219514
# differential_evolution step 384: f(x)= 27.000059158219514
# differential_evolution step 385: f(x)= 27.000059158219514
# differential_evolution step 386: f(x)= 27.000059158219514
# differential_evolution step 387: f(x)= 27.000059158219514
# differential_evolution step 388: f(x)= 27.000059158219514
# differential_evolution step 389: f(x)= 27.000059158219514
# differential_evolution step 390: f(x)= 27.000059158219514
# differential_evolution step 391: f(x)= 27.000059158219514
# differential_evolution step 392: f(x)= 27.000059158219514
# differential_evolution step 393: f(x)= 27.000059158219514
# differential_evolution step 394: f(x)= 27.000059158219514
# differential_evolution step 395: f(x)= 27.000059158219514
# differential_evolution step 396: f(x)= 27.000059158219514
# differential_evolution step 397: f(x)= 27.000059158219514
# differential_evolution step 398: f(x)= 27.000059158219514
# differential_evolution step 399: f(x)= 27.000059158219514
# differential_evolution step 400: f(x)= 27.000059158219514
# differential_evolution step 401: f(x)= 27.000059158219514
# differential_evolution step 402: f(x)= 27.000059158219514
# differential_evolution step 403: f(x)= 27.000059158219514
# differential_evolution step 404: f(x)= 27.000059158219514
# differential_evolution step 405: f(x)= 27.000059158219514
# differential_evolution step 406: f(x)= 27.000059158219514
# differential_evolution step 407: f(x)= 27.000059158219514
# differential_evolution step 408: f(x)= 27.000059158219514
# differential_evolution step 409: f(x)= 27.000059158219514
# differential_evolution step 410: f(x)= 27.000059158219514
# differential_evolution step 411: f(x)= 27.000059158219514
# differential_evolution step 412: f(x)= 27.000059158219514
# differential_evolution step 413: f(x)= 27.000059158219514
# differential_evolution step 414: f(x)= 27.000059158219514
# differential_evolution step 415: f(x)= 27.000059158219514
# differential_evolution step 416: f(x)= 27.000059158219514
# differential_evolution step 417: f(x)= 27.000059158219514
# differential_evolution step 418: f(x)= 27.000059158219514
# differential_evolution step 419: f(x)= 26.770080678523925
# differential_evolution step 420: f(x)= 26.770080678523925
# differential_evolution step 421: f(x)= 26.770080678523925
# differential_evolution step 422: f(x)= 26.770080678523925
# differential_evolution step 423: f(x)= 26.770080678523925
# differential_evolution step 424: f(x)= 26.770080678523925
# differential_evolution step 425: f(x)= 24.993231758538844
# differential_evolution step 426: f(x)= 24.993231758538844
# differential_evolution step 427: f(x)= 24.993231758538844
# differential_evolution step 428: f(x)= 24.993231758538844
# differential_evolution step 429: f(x)= 24.993231758538844
# differential_evolution step 430: f(x)= 24.993231758538844
# differential_evolution step 431: f(x)= 24.993231758538844
# differential_evolution step 432: f(x)= 24.993231758538844
# differential_evolution step 433: f(x)= 24.338534990923577
# differential_evolution step 434: f(x)= 24.338534990923577
# differential_evolution step 435: f(x)= 24.338534990923577
# differential_evolution step 436: f(x)= 23.75745713554431
# differential_evolution step 437: f(x)= 23.69682158518684
# differential_evolution step 438: f(x)= 23.69682158518684
# differential_evolution step 439: f(x)= 23.69682158518684
# differential_evolution step 440: f(x)= 23.69682158518684
# differential_evolution step 441: f(x)= 23.69682158518684
# differential_evolution step 442: f(x)= 23.69682158518684
# differential_evolution step 443: f(x)= 23.69682158518684
# differential_evolution step 444: f(x)= 23.69682158518684
# differential_evolution step 445: f(x)= 23.69682158518684
# differential_evolution step 446: f(x)= 23.69682158518684
# differential_evolution step 447: f(x)= 23.69682158518684
# differential_evolution step 448: f(x)= 23.69682158518684
# differential_evolution step 449: f(x)= 23.69682158518684
# differential_evolution step 450: f(x)= 23.69682158518684
# differential_evolution step 451: f(x)= 23.69682158518684
# differential_evolution step 452: f(x)= 23.69682158518684
# differential_evolution step 453: f(x)= 23.69682158518684
# differential_evolution step 454: f(x)= 23.69682158518684
# differential_evolution step 455: f(x)= 23.69682158518684
# differential_evolution step 456: f(x)= 23.69682158518684
# differential_evolution step 457: f(x)= 23.69682158518684
# differential_evolution step 458: f(x)= 23.69682158518684
# differential_evolution step 459: f(x)= 23.69682158518684
# differential_evolution step 460: f(x)= 23.69682158518684
# differential_evolution step 461: f(x)= 23.69682158518684
# differential_evolution step 462: f(x)= 23.69682158518684
# differential_evolution step 463: f(x)= 23.69682158518684
# differential_evolution step 464: f(x)= 23.69682158518684
# differential_evolution step 465: f(x)= 23.69682158518684
# differential_evolution step 466: f(x)= 23.69682158518684
# differential_evolution step 467: f(x)= 23.69682158518684
# differential_evolution step 468: f(x)= 23.69682158518684
# differential_evolution step 469: f(x)= 23.69682158518684
# differential_evolution step 470: f(x)= 23.69682158518684
# differential_evolution step 471: f(x)= 23.69682158518684
# differential_evolution step 472: f(x)= 23.69682158518684
# differential_evolution step 473: f(x)= 23.69682158518684
# differential_evolution step 474: f(x)= 23.69682158518684
# differential_evolution step 475: f(x)= 23.69682158518684
# differential_evolution step 476: f(x)= 23.69682158518684
# differential_evolution step 477: f(x)= 23.69682158518684
# differential_evolution step 478: f(x)= 23.69682158518684
# differential_evolution step 479: f(x)= 23.69682158518684
# differential_evolution step 480: f(x)= 23.69682158518684
# differential_evolution step 481: f(x)= 23.69682158518684
# differential_evolution step 482: f(x)= 23.69682158518684
# differential_evolution step 483: f(x)= 23.69682158518684
# differential_evolution step 484: f(x)= 23.69682158518684
# differential_evolution step 485: f(x)= 23.69682158518684
# differential_evolution step 486: f(x)= 23.69682158518684
# differential_evolution step 487: f(x)= 23.69682158518684
# differential_evolution step 488: f(x)= 23.69682158518684
# differential_evolution step 489: f(x)= 23.69682158518684
# differential_evolution step 490: f(x)= 23.69682158518684
# differential_evolution step 491: f(x)= 23.278623346583146
# differential_evolution step 492: f(x)= 23.278623346583146
# differential_evolution step 493: f(x)= 23.278623346583146
# differential_evolution step 494: f(x)= 23.278623346583146
# differential_evolution step 495: f(x)= 23.278623346583146
# differential_evolution step 496: f(x)= 22.41202488286948
# differential_evolution step 497: f(x)= 22.41202488286948
# differential_evolution step 498: f(x)= 22.41202488286948
# differential_evolution step 499: f(x)= 22.41202488286948
# differential_evolution step 500: f(x)= 22.41202488286948
# differential_evolution step 501: f(x)= 22.41202488286948
# differential_evolution step 502: f(x)= 22.41202488286948
# differential_evolution step 503: f(x)= 22.41202488286948
# differential_evolution step 504: f(x)= 22.41202488286948
# differential_evolution step 505: f(x)= 22.41202488286948
# differential_evolution step 506: f(x)= 22.41202488286948
# differential_evolution step 507: f(x)= 22.41202488286948
# differential_evolution step 508: f(x)= 22.41202488286948
# differential_evolution step 509: f(x)= 22.41202488286948
# differential_evolution step 510: f(x)= 22.41202488286948
# differential_evolution step 511: f(x)= 22.41202488286948
# differential_evolution step 512: f(x)= 22.41202488286948
# differential_evolution step 513: f(x)= 22.206789071113107
# differential_evolution step 514: f(x)= 22.206789071113107
# differential_evolution step 515: f(x)= 22.206789071113107
# differential_evolution step 516: f(x)= 22.206789071113107
# differential_evolution step 517: f(x)= 22.206789071113107
# differential_evolution step 518: f(x)= 22.206789071113107
# differential_evolution step 519: f(x)= 22.206789071113107
# differential_evolution step 520: f(x)= 22.016044659785862
# differential_evolution step 521: f(x)= 22.016044659785862
# differential_evolution step 522: f(x)= 22.016044659785862
# differential_evolution step 523: f(x)= 22.016044659785862
# differential_evolution step 524: f(x)= 22.016044659785862
# differential_evolution step 525: f(x)= 22.016044659785862
# differential_evolution step 526: f(x)= 22.016044659785862
# differential_evolution step 527: f(x)= 22.016044659785862
# differential_evolution step 528: f(x)= 22.016044659785862
# differential_evolution step 529: f(x)= 22.016044659785862
# differential_evolution step 530: f(x)= 22.016044659785862
# differential_evolution step 531: f(x)= 22.016044659785862
# differential_evolution step 532: f(x)= 22.016044659785862
# differential_evolution step 533: f(x)= 22.016044659785862
# differential_evolution step 534: f(x)= 22.016044659785862
# differential_evolution step 535: f(x)= 22.016044659785862
# differential_evolution step 536: f(x)= 22.016044659785862
# differential_evolution step 537: f(x)= 22.016044659785862
# differential_evolution step 538: f(x)= 22.016044659785862
# differential_evolution step 539: f(x)= 22.016044659785862
# differential_evolution step 540: f(x)= 22.016044659785862
# differential_evolution step 541: f(x)= 22.016044659785862
# differential_evolution step 542: f(x)= 22.016044659785862
# differential_evolution step 543: f(x)= 22.016044659785862
# differential_evolution step 544: f(x)= 22.016044659785862
# differential_evolution step 545: f(x)= 22.016044659785862
# differential_evolution step 546: f(x)= 22.016044659785862
# differential_evolution step 547: f(x)= 22.016044659785862
# differential_evolution step 548: f(x)= 22.016044659785862
# differential_evolution step 549: f(x)= 22.016044659785862
# differential_evolution step 550: f(x)= 22.016044659785862
# differential_evolution step 551: f(x)= 22.016044659785862
# differential_evolution step 552: f(x)= 22.016044659785862
# differential_evolution step 553: f(x)= 21.948682754687397
# differential_evolution step 554: f(x)= 21.948682754687397
# differential_evolution step 555: f(x)= 21.76758614872765
# differential_evolution step 556: f(x)= 21.76758614872765
# differential_evolution step 557: f(x)= 21.76758614872765
# differential_evolution step 558: f(x)= 21.76758614872765
# differential_evolution step 559: f(x)= 21.76758614872765
# differential_evolution step 560: f(x)= 21.76758614872765
# differential_evolution step 561: f(x)= 21.17067438870631
# differential_evolution step 562: f(x)= 21.17067438870631
# differential_evolution step 563: f(x)= 21.17067438870631
# differential_evolution step 564: f(x)= 21.17067438870631
# differential_evolution step 565: f(x)= 21.17067438870631
# differential_evolution step 566: f(x)= 21.17067438870631
# differential_evolution step 567: f(x)= 21.17067438870631
# differential_evolution step 568: f(x)= 21.17067438870631
# differential_evolution step 569: f(x)= 21.17067438870631
# differential_evolution step 570: f(x)= 21.17067438870631
# differential_evolution step 571: f(x)= 21.17067438870631
# differential_evolution step 572: f(x)= 21.17067438870631
# differential_evolution step 573: f(x)= 21.17067438870631
# differential_evolution step 574: f(x)= 21.17067438870631
# differential_evolution step 575: f(x)= 21.17067438870631
# differential_evolution step 576: f(x)= 21.17067438870631
# differential_evolution step 577: f(x)= 21.17067438870631
# differential_evolution step 578: f(x)= 21.17067438870631
# differential_evolution step 579: f(x)= 21.17067438870631
# differential_evolution step 580: f(x)= 21.17067438870631
# differential_evolution step 581: f(x)= 21.17067438870631
# differential_evolution step 582: f(x)= 21.17067438870631
# differential_evolution step 583: f(x)= 21.17067438870631
# differential_evolution step 584: f(x)= 21.17067438870631
# differential_evolution step 585: f(x)= 21.17067438870631
# differential_evolution step 586: f(x)= 21.17067438870631
# differential_evolution step 587: f(x)= 21.17067438870631
# differential_evolution step 588: f(x)= 21.17067438870631
# differential_evolution step 589: f(x)= 21.17067438870631
# differential_evolution step 590: f(x)= 21.17067438870631
# differential_evolution step 591: f(x)= 21.17067438870631
# differential_evolution step 592: f(x)= 21.17067438870631
# differential_evolution step 593: f(x)= 21.17067438870631
# differential_evolution step 594: f(x)= 21.17067438870631
# differential_evolution step 595: f(x)= 21.17067438870631
# differential_evolution step 596: f(x)= 21.17067438870631
# differential_evolution step 597: f(x)= 21.17067438870631
# differential_evolution step 598: f(x)= 21.17067438870631
# differential_evolution step 599: f(x)= 21.17067438870631
# differential_evolution step 600: f(x)= 21.17067438870631
# differential_evolution step 601: f(x)= 21.17067438870631
# differential_evolution step 602: f(x)= 21.17067438870631
# differential_evolution step 603: f(x)= 21.17067438870631
# differential_evolution step 604: f(x)= 21.17067438870631
# differential_evolution step 605: f(x)= 21.17067438870631
# differential_evolution step 606: f(x)= 21.112462379889575
# differential_evolution step 607: f(x)= 21.112462379889575
# differential_evolution step 608: f(x)= 21.112462379889575
# differential_evolution step 609: f(x)= 21.112462379889575
# differential_evolution step 610: f(x)= 21.112462379889575
# differential_evolution step 611: f(x)= 21.112462379889575
# differential_evolution step 612: f(x)= 21.112462379889575
# differential_evolution step 613: f(x)= 21.112462379889575
# differential_evolution step 614: f(x)= 21.112462379889575
# differential_evolution step 615: f(x)= 21.112462379889575
# differential_evolution step 616: f(x)= 21.112462379889575
# differential_evolution step 617: f(x)= 21.112462379889575
# differential_evolution step 618: f(x)= 21.112462379889575
# differential_evolution step 619: f(x)= 21.112462379889575
# differential_evolution step 620: f(x)= 21.112462379889575
# differential_evolution step 621: f(x)= 21.112462379889575
# differential_evolution step 622: f(x)= 21.112462379889575
# differential_evolution step 623: f(x)= 21.112462379889575
# differential_evolution step 624: f(x)= 21.112462379889575
# differential_evolution step 625: f(x)= 21.112462379889575
# differential_evolution step 626: f(x)= 21.112462379889575
# differential_evolution step 627: f(x)= 21.112462379889575
# differential_evolution step 628: f(x)= 21.112462379889575
# differential_evolution step 629: f(x)= 21.112462379889575
# differential_evolution step 630: f(x)= 21.112462379889575
# differential_evolution step 631: f(x)= 21.112462379889575
# differential_evolution step 632: f(x)= 21.112462379889575
# differential_evolution step 633: f(x)= 21.112462379889575
# differential_evolution step 634: f(x)= 21.112462379889575
# differential_evolution step 635: f(x)= 20.655803597896174
# differential_evolution step 636: f(x)= 20.655803597896174
# differential_evolution step 637: f(x)= 20.655803597896174
# differential_evolution step 638: f(x)= 20.655803597896174
# differential_evolution step 639: f(x)= 20.655803597896174
# differential_evolution step 640: f(x)= 20.655803597896174
# differential_evolution step 641: f(x)= 20.655803597896174
# differential_evolution step 642: f(x)= 20.655803597896174
# differential_evolution step 643: f(x)= 20.655803597896174
# differential_evolution step 644: f(x)= 20.655803597896174
# differential_evolution step 645: f(x)= 20.655803597896174
# differential_evolution step 646: f(x)= 20.655803597896174
# differential_evolution step 647: f(x)= 20.655803597896174
# differential_evolution step 648: f(x)= 20.655803597896174
# differential_evolution step 649: f(x)= 20.655803597896174
# differential_evolution step 650: f(x)= 20.655803597896174
# differential_evolution step 651: f(x)= 20.655803597896174
# differential_evolution step 652: f(x)= 20.655803597896174
# differential_evolution step 653: f(x)= 20.655803597896174
# differential_evolution step 654: f(x)= 20.655803597896174
# differential_evolution step 655: f(x)= 20.655803597896174
# differential_evolution step 656: f(x)= 20.655803597896174
# differential_evolution step 657: f(x)= 20.655803597896174
# differential_evolution step 658: f(x)= 20.655803597896174
# differential_evolution step 659: f(x)= 20.655803597896174
# differential_evolution step 660: f(x)= 20.655803597896174
# differential_evolution step 661: f(x)= 20.655803597896174
# differential_evolution step 662: f(x)= 20.270364704863105
# differential_evolution step 663: f(x)= 20.270364704863105
# differential_evolution step 664: f(x)= 20.270364704863105
# differential_evolution step 665: f(x)= 20.270364704863105
# differential_evolution step 666: f(x)= 20.270364704863105
# differential_evolution step 667: f(x)= 20.270364704863105
# differential_evolution step 668: f(x)= 20.270364704863105
# differential_evolution step 669: f(x)= 20.270364704863105
# differential_evolution step 670: f(x)= 20.270364704863105
# differential_evolution step 671: f(x)= 20.270364704863105
# differential_evolution step 672: f(x)= 20.270364704863105
# differential_evolution step 673: f(x)= 20.270364704863105
# differential_evolution step 674: f(x)= 20.270364704863105
# differential_evolution step 675: f(x)= 20.270364704863105
# differential_evolution step 676: f(x)= 20.270364704863105
# differential_evolution step 677: f(x)= 20.270364704863105
# differential_evolution step 678: f(x)= 20.270364704863105
# differential_evolution step 679: f(x)= 20.270364704863105
# differential_evolution step 680: f(x)= 20.270364704863105
# differential_evolution step 681: f(x)= 20.270364704863105
# differential_evolution step 682: f(x)= 20.270364704863105
# differential_evolution step 683: f(x)= 20.270364704863105
# differential_evolution step 684: f(x)= 20.270364704863105
# differential_evolution step 685: f(x)= 20.270364704863105
# differential_evolution step 686: f(x)= 20.270364704863105
# differential_evolution step 687: f(x)= 20.270364704863105
# differential_evolution step 688: f(x)= 20.270364704863105
# differential_evolution step 689: f(x)= 20.144923116032828
# differential_evolution step 690: f(x)= 20.144923116032828
# differential_evolution step 691: f(x)= 20.144923116032828
# differential_evolution step 692: f(x)= 20.144923116032828
# differential_evolution step 693: f(x)= 20.144923116032828
# differential_evolution step 694: f(x)= 20.144923116032828
# differential_evolution step 695: f(x)= 19.923671184730424
# differential_evolution step 696: f(x)= 19.923671184730424
# differential_evolution step 697: f(x)= 19.923671184730424
# differential_evolution step 698: f(x)= 19.923671184730424
# differential_evolution step 699: f(x)= 19.923671184730424
# differential_evolution step 700: f(x)= 19.923671184730424
# differential_evolution step 701: f(x)= 19.923671184730424
# differential_evolution step 702: f(x)= 19.923671184730424
# differential_evolution step 703: f(x)= 19.923671184730424
# differential_evolution step 704: f(x)= 19.923671184730424
# differential_evolution step 705: f(x)= 19.923671184730424
# differential_evolution step 706: f(x)= 19.923671184730424
# differential_evolution step 707: f(x)= 19.486143808174464
# differential_evolution step 708: f(x)= 19.486143808174464
# differential_evolution step 709: f(x)= 19.486143808174464
# differential_evolution step 710: f(x)= 19.486143808174464
# differential_evolution step 711: f(x)= 19.486143808174464
# differential_evolution step 712: f(x)= 19.486143808174464
# differential_evolution step 713: f(x)= 19.486143808174464
# differential_evolution step 714: f(x)= 19.486143808174464
# differential_evolution step 715: f(x)= 19.486143808174464
# differential_evolution step 716: f(x)= 19.486143808174464
# differential_evolution step 717: f(x)= 19.486143808174464
# differential_evolution step 718: f(x)= 19.486143808174464
# differential_evolution step 719: f(x)= 19.486143808174464
# differential_evolution step 720: f(x)= 19.486143808174464
# differential_evolution step 721: f(x)= 19.486143808174464
# differential_evolution step 722: f(x)= 19.486143808174464
# differential_evolution step 723: f(x)= 19.486143808174464
# differential_evolution step 724: f(x)= 19.486143808174464
# differential_evolution step 725: f(x)= 19.486143808174464
# differential_evolution step 726: f(x)= 19.486143808174464
# differential_evolution step 727: f(x)= 19.486143808174464
# differential_evolution step 728: f(x)= 19.486143808174464
# differential_evolution step 729: f(x)= 19.486143808174464
# differential_evolution step 730: f(x)= 19.486143808174464
# differential_evolution step 731: f(x)= 19.486143808174464
# differential_evolution step 732: f(x)= 19.486143808174464
# differential_evolution step 733: f(x)= 19.486143808174464
# differential_evolution step 734: f(x)= 19.486143808174464
# differential_evolution step 735: f(x)= 19.486143808174464
# differential_evolution step 736: f(x)= 19.486143808174464
# differential_evolution step 737: f(x)= 19.486143808174464
# differential_evolution step 738: f(x)= 19.486143808174464
# differential_evolution step 739: f(x)= 19.486143808174464
# differential_evolution step 740: f(x)= 19.486143808174464
# differential_evolution step 741: f(x)= 19.486143808174464
# differential_evolution step 742: f(x)= 19.486143808174464
# differential_evolution step 743: f(x)= 19.486143808174464
# differential_evolution step 744: f(x)= 19.486143808174464
# differential_evolution step 745: f(x)= 19.486143808174464
# differential_evolution step 746: f(x)= 19.486143808174464
# differential_evolution step 747: f(x)= 19.486143808174464
# differential_evolution step 748: f(x)= 19.486143808174464
# differential_evolution step 749: f(x)= 19.486143808174464
# differential_evolution step 750: f(x)= 19.486143808174464
# differential_evolution step 751: f(x)= 19.486143808174464
# differential_evolution step 752: f(x)= 19.486143808174464
# differential_evolution step 753: f(x)= 19.486143808174464
# differential_evolution step 754: f(x)= 19.486143808174464
# differential_evolution step 755: f(x)= 19.486143808174464
# differential_evolution step 756: f(x)= 19.486143808174464
# differential_evolution step 757: f(x)= 19.486143808174464
# differential_evolution step 758: f(x)= 19.486143808174464
# differential_evolution step 759: f(x)= 19.486143808174464
# differential_evolution step 760: f(x)= 19.486143808174464
# differential_evolution step 761: f(x)= 19.486143808174464
# differential_evolution step 762: f(x)= 19.486143808174464
# differential_evolution step 763: f(x)= 19.486143808174464
# differential_evolution step 764: f(x)= 19.486143808174464
# differential_evolution step 765: f(x)= 19.486143808174464
# differential_evolution step 766: f(x)= 19.486143808174464
# differential_evolution step 767: f(x)= 19.486143808174464
# differential_evolution step 768: f(x)= 19.486143808174464
# differential_evolution step 769: f(x)= 19.486143808174464
# differential_evolution step 770: f(x)= 19.486143808174464
# differential_evolution step 771: f(x)= 19.486143808174464
# differential_evolution step 772: f(x)= 19.486143808174464
# differential_evolution step 773: f(x)= 19.486143808174464
# differential_evolution step 774: f(x)= 19.486143808174464
# differential_evolution step 775: f(x)= 19.486143808174464
# differential_evolution step 776: f(x)= 19.486143808174464
# differential_evolution step 777: f(x)= 19.486143808174464
# differential_evolution step 778: f(x)= 19.486143808174464
# differential_evolution step 779: f(x)= 19.486143808174464
# differential_evolution step 780: f(x)= 19.486143808174464
# differential_evolution step 781: f(x)= 19.486143808174464
# differential_evolution step 782: f(x)= 19.486143808174464
# differential_evolution step 783: f(x)= 19.486143808174464
# differential_evolution step 784: f(x)= 19.486143808174464
# differential_evolution step 785: f(x)= 19.486143808174464
# differential_evolution step 786: f(x)= 19.486143808174464
# differential_evolution step 787: f(x)= 19.486143808174464
# differential_evolution step 788: f(x)= 19.486143808174464
# differential_evolution step 789: f(x)= 19.486143808174464
# differential_evolution step 790: f(x)= 19.486143808174464
# differential_evolution step 791: f(x)= 19.486143808174464
# differential_evolution step 792: f(x)= 19.486143808174464
# differential_evolution step 793: f(x)= 19.486143808174464
# differential_evolution step 794: f(x)= 19.486143808174464
# differential_evolution step 795: f(x)= 19.486143808174464
# differential_evolution step 796: f(x)= 19.486143808174464
# differential_evolution step 797: f(x)= 19.486143808174464
# differential_evolution step 798: f(x)= 19.486143808174464
# differential_evolution step 799: f(x)= 19.486143808174464
# differential_evolution step 800: f(x)= 19.486143808174464
# differential_evolution step 801: f(x)= 19.486143808174464
# differential_evolution step 802: f(x)= 19.486143808174464
# differential_evolution step 803: f(x)= 19.486143808174464
# differential_evolution step 804: f(x)= 19.486143808174464
# differential_evolution step 805: f(x)= 19.486143808174464
# differential_evolution step 806: f(x)= 19.486143808174464
# differential_evolution step 807: f(x)= 19.486143808174464
# differential_evolution step 808: f(x)= 19.486143808174464
# differential_evolution step 809: f(x)= 19.486143808174464
# differential_evolution step 810: f(x)= 19.486143808174464
# differential_evolution step 811: f(x)= 19.486143808174464
# differential_evolution step 812: f(x)= 19.486143808174464
# differential_evolution step 813: f(x)= 19.486143808174464
# differential_evolution step 814: f(x)= 19.486143808174464
# differential_evolution step 815: f(x)= 19.486143808174464
# differential_evolution step 816: f(x)= 19.34360998187277
# differential_evolution step 817: f(x)= 19.307763588331177
# differential_evolution step 818: f(x)= 19.307763588331177
# differential_evolution step 819: f(x)= 19.307763588331177
# differential_evolution step 820: f(x)= 19.307763588331177
# differential_evolution step 821: f(x)= 19.307763588331177
# differential_evolution step 822: f(x)= 19.307763588331177
# differential_evolution step 823: f(x)= 19.307763588331177
# differential_evolution step 824: f(x)= 19.307763588331177
# differential_evolution step 825: f(x)= 19.307763588331177
# differential_evolution step 826: f(x)= 19.307763588331177
# differential_evolution step 827: f(x)= 19.307763588331177
# differential_evolution step 828: f(x)= 19.307763588331177
# differential_evolution step 829: f(x)= 19.307763588331177
# differential_evolution step 830: f(x)= 19.307763588331177
# differential_evolution step 831: f(x)= 19.307763588331177
# differential_evolution step 832: f(x)= 19.307763588331177
# differential_evolution step 833: f(x)= 19.307763588331177
# differential_evolution step 834: f(x)= 19.307763588331177
# differential_evolution step 835: f(x)= 19.307763588331177
# differential_evolution step 836: f(x)= 19.307763588331177
# differential_evolution step 837: f(x)= 19.307763588331177
# differential_evolution step 838: f(x)= 19.307763588331177
# differential_evolution step 839: f(x)= 19.307763588331177
# differential_evolution step 840: f(x)= 19.307763588331177
# differential_evolution step 841: f(x)= 19.307763588331177
# differential_evolution step 842: f(x)= 19.307763588331177
# differential_evolution step 843: f(x)= 19.307763588331177
# differential_evolution step 844: f(x)= 19.307763588331177
# differential_evolution step 845: f(x)= 19.306137710384515
# differential_evolution step 846: f(x)= 19.306137710384515
# differential_evolution step 847: f(x)= 19.226675535941414
# differential_evolution step 848: f(x)= 19.226675535941414
# differential_evolution step 849: f(x)= 19.226675535941414
# differential_evolution step 850: f(x)= 19.226675535941414
# differential_evolution step 851: f(x)= 19.226675535941414
# differential_evolution step 852: f(x)= 19.226675535941414
# differential_evolution step 853: f(x)= 19.226675535941414
# differential_evolution step 854: f(x)= 19.226675535941414
# differential_evolution step 855: f(x)= 19.226675535941414
# differential_evolution step 856: f(x)= 19.226675535941414
# differential_evolution step 857: f(x)= 19.226675535941414
# differential_evolution step 858: f(x)= 19.226675535941414
# differential_evolution step 859: f(x)= 19.226675535941414
# differential_evolution step 860: f(x)= 19.226675535941414
# differential_evolution step 861: f(x)= 19.226675535941414
# differential_evolution step 862: f(x)= 19.226675535941414
# differential_evolution step 863: f(x)= 19.226675535941414
# differential_evolution step 864: f(x)= 19.226675535941414
# differential_evolution step 865: f(x)= 19.226675535941414
# differential_evolution step 866: f(x)= 19.226675535941414
# differential_evolution step 867: f(x)= 19.226675535941414
# differential_evolution step 868: f(x)= 19.226675535941414
# differential_evolution step 869: f(x)= 19.177537384418223
# differential_evolution step 870: f(x)= 19.177537384418223
# differential_evolution step 871: f(x)= 19.177537384418223
# differential_evolution step 872: f(x)= 19.177537384418223
# differential_evolution step 873: f(x)= 19.177537384418223
# differential_evolution step 874: f(x)= 19.177537384418223
# differential_evolution step 875: f(x)= 19.134028889446405
# differential_evolution step 876: f(x)= 19.134028889446405
# differential_evolution step 877: f(x)= 19.134028889446405
# differential_evolution step 878: f(x)= 19.134028889446405
# differential_evolution step 879: f(x)= 19.134028889446405
# differential_evolution step 880: f(x)= 19.134028889446405
# differential_evolution step 881: f(x)= 19.134028889446405
# differential_evolution step 882: f(x)= 19.134028889446405
# differential_evolution step 883: f(x)= 19.134028889446405
# differential_evolution step 884: f(x)= 19.134028889446405
# differential_evolution step 885: f(x)= 19.044511215629115
# differential_evolution step 886: f(x)= 19.044511215629115
# differential_evolution step 887: f(x)= 19.044511215629115
# differential_evolution step 888: f(x)= 18.898189407571355
# differential_evolution step 889: f(x)= 18.898189407571355
# differential_evolution step 890: f(x)= 18.898189407571355
# differential_evolution step 891: f(x)= 18.898189407571355
# differential_evolution step 892: f(x)= 18.898189407571355
# differential_evolution step 893: f(x)= 18.898189407571355
# differential_evolution step 894: f(x)= 18.898189407571355
# differential_evolution step 895: f(x)= 18.898189407571355
# differential_evolution step 896: f(x)= 18.898189407571355
# differential_evolution step 897: f(x)= 18.898189407571355
# differential_evolution step 898: f(x)= 18.898189407571355
# differential_evolution step 899: f(x)= 18.898189407571355
# differential_evolution step 900: f(x)= 18.898189407571355
# differential_evolution step 901: f(x)= 18.898189407571355
# differential_evolution step 902: f(x)= 18.898189407571355
# differential_evolution step 903: f(x)= 18.898189407571355
# differential_evolution step 904: f(x)= 18.898189407571355
# differential_evolution step 905: f(x)= 18.898189407571355
# differential_evolution step 906: f(x)= 18.898189407571355
# differential_evolution step 907: f(x)= 18.898189407571355
# differential_evolution step 908: f(x)= 18.898189407571355
# differential_evolution step 909: f(x)= 18.898189407571355
# differential_evolution step 910: f(x)= 18.898189407571355
# differential_evolution step 911: f(x)= 18.898189407571355
# differential_evolution step 912: f(x)= 18.898189407571355
# differential_evolution step 913: f(x)= 18.898189407571355
# differential_evolution step 914: f(x)= 18.898189407571355
# differential_evolution step 915: f(x)= 18.898189407571355
# differential_evolution step 916: f(x)= 18.898189407571355
# differential_evolution step 917: f(x)= 18.898189407571355
# differential_evolution step 918: f(x)= 18.898189407571355
# differential_evolution step 919: f(x)= 18.898189407571355
# differential_evolution step 920: f(x)= 18.898189407571355
# differential_evolution step 921: f(x)= 18.898189407571355
# differential_evolution step 922: f(x)= 18.898189407571355
# differential_evolution step 923: f(x)= 18.898189407571355
# differential_evolution step 924: f(x)= 18.898189407571355
# differential_evolution step 925: f(x)= 18.898189407571355
# differential_evolution step 926: f(x)= 18.898189407571355
# differential_evolution step 927: f(x)= 18.898189407571355
# differential_evolution step 928: f(x)= 18.898189407571355
# differential_evolution step 929: f(x)= 18.898189407571355
# differential_evolution step 930: f(x)= 18.898189407571355
# differential_evolution step 931: f(x)= 18.898189407571355
# differential_evolution step 932: f(x)= 18.898189407571355
# differential_evolution step 933: f(x)= 18.898189407571355
# differential_evolution step 934: f(x)= 18.898189407571355
# differential_evolution step 935: f(x)= 18.898189407571355
# differential_evolution step 936: f(x)= 18.898189407571355
# differential_evolution step 937: f(x)= 18.898189407571355
# differential_evolution step 938: f(x)= 18.898189407571355
# differential_evolution step 939: f(x)= 18.898189407571355
# differential_evolution step 940: f(x)= 18.898189407571355
# differential_evolution step 941: f(x)= 18.898189407571355
# differential_evolution step 942: f(x)= 18.898189407571355
# differential_evolution step 943: f(x)= 18.898189407571355
# differential_evolution step 944: f(x)= 18.898189407571355
# differential_evolution step 945: f(x)= 18.898189407571355
# differential_evolution step 946: f(x)= 18.898189407571355
# differential_evolution step 947: f(x)= 18.898189407571355
# differential_evolution step 948: f(x)= 18.898189407571355
# differential_evolution step 949: f(x)= 18.898189407571355
# differential_evolution step 950: f(x)= 18.898189407571355
# differential_evolution step 951: f(x)= 18.813027472736504
# differential_evolution step 952: f(x)= 18.813027472736504
# differential_evolution step 953: f(x)= 18.813027472736504
# differential_evolution step 954: f(x)= 18.813027472736504
# differential_evolution step 955: f(x)= 18.813027472736504
# differential_evolution step 956: f(x)= 18.813027472736504
# differential_evolution step 957: f(x)= 18.813027472736504
# differential_evolution step 958: f(x)= 18.813027472736504
# differential_evolution step 959: f(x)= 18.813027472736504
# differential_evolution step 960: f(x)= 18.813027472736504
# differential_evolution step 961: f(x)= 18.813027472736504
# differential_evolution step 962: f(x)= 18.813027472736504
# differential_evolution step 963: f(x)= 18.813027472736504
# differential_evolution step 964: f(x)= 18.813027472736504
# differential_evolution step 965: f(x)= 18.813027472736504
# differential_evolution step 966: f(x)= 18.813027472736504
# differential_evolution step 967: f(x)= 18.813027472736504
# differential_evolution step 968: f(x)= 18.813027472736504
# differential_evolution step 969: f(x)= 18.813027472736504
# differential_evolution step 970: f(x)= 18.813027472736504
# differential_evolution step 971: f(x)= 18.813027472736504
# differential_evolution step 972: f(x)= 18.813027472736504
# differential_evolution step 973: f(x)= 18.813027472736504
# differential_evolution step 974: f(x)= 18.813027472736504
# differential_evolution step 975: f(x)= 18.813027472736504
# differential_evolution step 976: f(x)= 18.813027472736504
# differential_evolution step 977: f(x)= 18.813027472736504
# differential_evolution step 978: f(x)= 18.813027472736504
# differential_evolution step 979: f(x)= 18.813027472736504
# differential_evolution step 980: f(x)= 18.813027472736504
# differential_evolution step 981: f(x)= 18.813027472736504
# differential_evolution step 982: f(x)= 18.813027472736504
# differential_evolution step 983: f(x)= 18.813027472736504
# differential_evolution step 984: f(x)= 18.813027472736504
# differential_evolution step 985: f(x)= 18.813027472736504
# differential_evolution step 986: f(x)= 18.813027472736504
# differential_evolution step 987: f(x)= 18.813027472736504
# differential_evolution step 988: f(x)= 18.779928882064727
# differential_evolution step 989: f(x)= 18.779928882064727
# differential_evolution step 990: f(x)= 18.779928882064727
# differential_evolution step 991: f(x)= 18.779928882064727
# differential_evolution step 992: f(x)= 18.779928882064727
# differential_evolution step 993: f(x)= 18.779928882064727
# differential_evolution step 994: f(x)= 18.779928882064727
# differential_evolution step 995: f(x)= 18.779928882064727
# differential_evolution step 996: f(x)= 18.779928882064727
# differential_evolution step 997: f(x)= 18.779928882064727
# differential_evolution step 998: f(x)= 18.779928882064727
# differential_evolution step 999: f(x)= 18.779928882064727
# differential_evolution step 1000: f(x)= 18.779928882064727
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5400\3111683727.py:11: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.5351, r_e=10.0000, n=1.7696, x_0=16.6857
# Sérsic 2: I_e=5.4982, r_e=2.5762, n=2.7101, x_0=41.6235
# Sérsic 3: I_e=0.9890, r_e=25.2459, n=1.8861, x_0=65.9756
# Sérsic 4: I_e=4.3133, r_e=6.8223, n=0.3210, x_0=63.7285
# Sérsic 5: I_e=0.2710, r_e=4.8804, n=2.5925, x_0=73.0005
# Sérsic 6: I_e=0.1000, r_e=5.0000, n=1.9252, x_0=91.4734
# Chi quadro minimo: 17.752552370286352
# False

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=0.5351, r_e=10.0000, n=1.7696, x_0=16.6857
# Sérsic 2: I_e=5.4982, r_e=2.5762, n=2.7101, x_0=41.6235
# Sérsic 3: I_e=0.9890, r_e=25.2459, n=1.8861, x_0=65.9756
# Sérsic 4: I_e=4.3133, r_e=6.8223, n=0.3210, x_0=63.7285
# Sérsic 5: I_e=0.2710, r_e=4.8804, n=2.5925, x_0=73.0005
# Sérsic 6: I_e=0.1000, r_e=5.0000, n=1.9252, x_0=91.4734
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = real_errors_SII, bounds = bounds_list)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4602, r_e=10.0000, n=1.8839, x_0=16.5619
# Sérsic 2: I_e=2.9310, r_e=3.4375, n=3.4926, x_0=41.5775
# Sérsic 3: I_e=0.3676, r_e=49.9989, n=2.5119, x_0=65.9756
# Sérsic 4: I_e=4.8578, r_e=6.6840, n=0.3622, x_0=63.7285
# Sérsic 5: I_e=1.7656, r_e=2.1825, n=0.9496, x_0=72.9746
# Sérsic 6: I_e=0.1000, r_e=5.0000, n=1.7431, x_0=91.3193
# [5.40434022e-01 9.30181613e+00 1.07258365e+00 2.73310399e-02
#  2.23269889e+00 1.53934837e+00 8.05795107e-01 2.44038297e-02
#  5.82155797e-01 6.13492198e+01 1.08215497e+00 1.96480291e-01
#  1.05771785e+00 1.12540719e+00 7.93390841e-02 2.10440517e+00
#  1.44254349e+00 1.82389722e+00 6.21331401e-01 3.38545721e-01
#  6.10347369e-01 2.58940689e+01 4.41305386e+00 3.74966221e-01]
# 1.5067310553773219

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))
real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[2])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds =bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 13691.662852003348
# differential_evolution step 2: f(x)= 13691.662852003348
# differential_evolution step 3: f(x)= 13691.662852003348
# differential_evolution step 4: f(x)= 4627.89815925034
# differential_evolution step 5: f(x)= 4627.89815925034
# differential_evolution step 6: f(x)= 4627.89815925034
# differential_evolution step 7: f(x)= 4627.89815925034
# differential_evolution step 8: f(x)= 4627.89815925034
# differential_evolution step 9: f(x)= 4627.89815925034
# differential_evolution step 10: f(x)= 4627.89815925034
# differential_evolution step 11: f(x)= 2972.552419219845
# differential_evolution step 12: f(x)= 1944.2588697491594
# differential_evolution step 13: f(x)= 1944.2588697491594
# differential_evolution step 14: f(x)= 1720.418827024633
# differential_evolution step 15: f(x)= 1636.1932618283877
# differential_evolution step 16: f(x)= 1636.1932618283877
# differential_evolution step 17: f(x)= 1636.1932618283877
# differential_evolution step 18: f(x)= 1636.1932618283877
# differential_evolution step 19: f(x)= 1636.1932618283877
# differential_evolution step 20: f(x)= 1158.5913646624124
# differential_evolution step 21: f(x)= 836.2028620360609
# differential_evolution step 22: f(x)= 836.2028620360609
# differential_evolution step 23: f(x)= 836.2028620360609
# differential_evolution step 24: f(x)= 836.2028620360609
# differential_evolution step 25: f(x)= 836.2028620360609
# differential_evolution step 26: f(x)= 836.2028620360609
# differential_evolution step 27: f(x)= 836.2028620360609
# differential_evolution step 28: f(x)= 836.2028620360609
# differential_evolution step 29: f(x)= 836.2028620360609
# differential_evolution step 30: f(x)= 836.2028620360609
# differential_evolution step 31: f(x)= 836.2028620360609
# differential_evolution step 32: f(x)= 708.3205604997863
# differential_evolution step 33: f(x)= 707.9901309271396
# differential_evolution step 34: f(x)= 707.9901309271396
# differential_evolution step 35: f(x)= 707.9901309271396
# differential_evolution step 36: f(x)= 707.9901309271396
# differential_evolution step 37: f(x)= 707.9901309271396
# differential_evolution step 38: f(x)= 707.9901309271396
# differential_evolution step 39: f(x)= 471.0411016303639
# differential_evolution step 40: f(x)= 471.0411016303639
# differential_evolution step 41: f(x)= 471.0411016303639
# differential_evolution step 42: f(x)= 471.0411016303639
# differential_evolution step 43: f(x)= 471.0411016303639
# differential_evolution step 44: f(x)= 471.0411016303639
# differential_evolution step 45: f(x)= 471.0411016303639
# differential_evolution step 46: f(x)= 471.0411016303639
# differential_evolution step 47: f(x)= 471.0411016303639
# differential_evolution step 48: f(x)= 471.0411016303639
# differential_evolution step 49: f(x)= 471.0411016303639
# differential_evolution step 50: f(x)= 471.0411016303639
# differential_evolution step 51: f(x)= 471.0411016303639
# differential_evolution step 52: f(x)= 468.6164562241005
# differential_evolution step 53: f(x)= 468.6164562241005
# differential_evolution step 54: f(x)= 468.6164562241005
# differential_evolution step 55: f(x)= 468.6164562241005
# differential_evolution step 56: f(x)= 468.6164562241005
# differential_evolution step 57: f(x)= 468.6164562241005
# differential_evolution step 58: f(x)= 468.6164562241005
# differential_evolution step 59: f(x)= 468.6164562241005
# differential_evolution step 60: f(x)= 468.6164562241005
# differential_evolution step 61: f(x)= 435.75886665439936
# differential_evolution step 62: f(x)= 435.75886665439936
# differential_evolution step 63: f(x)= 435.75886665439936
# differential_evolution step 64: f(x)= 435.75886665439936
# differential_evolution step 65: f(x)= 435.75886665439936
# differential_evolution step 66: f(x)= 435.75886665439936
# differential_evolution step 67: f(x)= 365.27487635037744
# differential_evolution step 68: f(x)= 365.27487635037744
# differential_evolution step 69: f(x)= 365.27487635037744
# differential_evolution step 70: f(x)= 365.27487635037744
# differential_evolution step 71: f(x)= 365.27487635037744
# differential_evolution step 72: f(x)= 365.27487635037744
# differential_evolution step 73: f(x)= 365.27487635037744
# differential_evolution step 74: f(x)= 249.28510099514384
# differential_evolution step 75: f(x)= 249.28510099514384
# differential_evolution step 76: f(x)= 249.28510099514384
# differential_evolution step 77: f(x)= 249.28510099514384
# differential_evolution step 78: f(x)= 249.28510099514384
# differential_evolution step 79: f(x)= 249.28510099514384
# differential_evolution step 80: f(x)= 249.28510099514384
# differential_evolution step 81: f(x)= 249.28510099514384
# differential_evolution step 82: f(x)= 249.28510099514384
# differential_evolution step 83: f(x)= 249.28510099514384
# differential_evolution step 84: f(x)= 249.28510099514384
# differential_evolution step 85: f(x)= 249.28510099514384
# differential_evolution step 86: f(x)= 249.28510099514384
# differential_evolution step 87: f(x)= 249.28510099514384
# differential_evolution step 88: f(x)= 180.9667484279413
# differential_evolution step 89: f(x)= 180.9667484279413
# differential_evolution step 90: f(x)= 180.9667484279413
# differential_evolution step 91: f(x)= 180.9667484279413
# differential_evolution step 92: f(x)= 180.9667484279413
# differential_evolution step 93: f(x)= 180.9667484279413
# differential_evolution step 94: f(x)= 180.9667484279413
# differential_evolution step 95: f(x)= 180.9667484279413
# differential_evolution step 96: f(x)= 180.9667484279413
# differential_evolution step 97: f(x)= 180.9667484279413
# differential_evolution step 98: f(x)= 180.9667484279413
# differential_evolution step 99: f(x)= 180.9667484279413
# differential_evolution step 100: f(x)= 180.9667484279413
# differential_evolution step 101: f(x)= 180.9667484279413
# differential_evolution step 102: f(x)= 180.9667484279413
# differential_evolution step 103: f(x)= 180.9667484279413
# differential_evolution step 104: f(x)= 180.9667484279413
# differential_evolution step 105: f(x)= 180.9667484279413
# differential_evolution step 106: f(x)= 180.9667484279413
# differential_evolution step 107: f(x)= 180.9667484279413
# differential_evolution step 108: f(x)= 180.9667484279413
# differential_evolution step 109: f(x)= 180.9667484279413
# differential_evolution step 110: f(x)= 145.26639037796556
# differential_evolution step 111: f(x)= 145.26639037796556
# differential_evolution step 112: f(x)= 145.26639037796556
# differential_evolution step 113: f(x)= 145.26639037796556
# differential_evolution step 114: f(x)= 116.61183889049614
# differential_evolution step 115: f(x)= 116.61183889049614
# differential_evolution step 116: f(x)= 116.61183889049614
# differential_evolution step 117: f(x)= 116.61183889049614
# differential_evolution step 118: f(x)= 116.61183889049614
# differential_evolution step 119: f(x)= 116.61183889049614
# differential_evolution step 120: f(x)= 116.61183889049614
# differential_evolution step 121: f(x)= 116.61183889049614
# differential_evolution step 122: f(x)= 116.61183889049614
# differential_evolution step 123: f(x)= 116.61183889049614
# differential_evolution step 124: f(x)= 116.61183889049614
# differential_evolution step 125: f(x)= 116.61183889049614
# differential_evolution step 126: f(x)= 116.61183889049614
# differential_evolution step 127: f(x)= 116.61183889049614
# differential_evolution step 128: f(x)= 116.61183889049614
# differential_evolution step 129: f(x)= 116.61183889049614
# differential_evolution step 130: f(x)= 116.61183889049614
# differential_evolution step 131: f(x)= 116.61183889049614
# differential_evolution step 132: f(x)= 116.61183889049614
# differential_evolution step 133: f(x)= 116.61183889049614
# differential_evolution step 134: f(x)= 116.61183889049614
# differential_evolution step 135: f(x)= 116.61183889049614
# differential_evolution step 136: f(x)= 116.61183889049614
# differential_evolution step 137: f(x)= 102.6420863109889
# differential_evolution step 138: f(x)= 102.6420863109889
# differential_evolution step 139: f(x)= 102.6420863109889
# differential_evolution step 140: f(x)= 102.6420863109889
# differential_evolution step 141: f(x)= 102.6420863109889
# differential_evolution step 142: f(x)= 102.6420863109889
# differential_evolution step 143: f(x)= 102.6420863109889
# differential_evolution step 144: f(x)= 102.6420863109889
# differential_evolution step 145: f(x)= 63.250812754596645
# differential_evolution step 146: f(x)= 63.250812754596645
# differential_evolution step 147: f(x)= 63.250812754596645
# differential_evolution step 148: f(x)= 63.250812754596645
# differential_evolution step 149: f(x)= 63.250812754596645
# differential_evolution step 150: f(x)= 63.250812754596645
# differential_evolution step 151: f(x)= 63.250812754596645
# differential_evolution step 152: f(x)= 63.250812754596645
# differential_evolution step 153: f(x)= 63.250812754596645
# differential_evolution step 154: f(x)= 63.250812754596645
# differential_evolution step 155: f(x)= 63.250812754596645
# differential_evolution step 156: f(x)= 63.250812754596645
# differential_evolution step 157: f(x)= 63.250812754596645
# differential_evolution step 158: f(x)= 63.250812754596645
# differential_evolution step 159: f(x)= 63.250812754596645
# differential_evolution step 160: f(x)= 63.250812754596645
# differential_evolution step 161: f(x)= 63.250812754596645
# differential_evolution step 162: f(x)= 63.250812754596645
# differential_evolution step 163: f(x)= 63.250812754596645
# differential_evolution step 164: f(x)= 63.250812754596645
# differential_evolution step 165: f(x)= 63.250812754596645
# differential_evolution step 166: f(x)= 63.250812754596645
# differential_evolution step 167: f(x)= 63.250812754596645
# differential_evolution step 168: f(x)= 63.250812754596645
# differential_evolution step 169: f(x)= 63.250812754596645
# differential_evolution step 170: f(x)= 63.250812754596645
# differential_evolution step 171: f(x)= 63.250812754596645
# differential_evolution step 172: f(x)= 63.250812754596645
# differential_evolution step 173: f(x)= 63.250812754596645
# differential_evolution step 174: f(x)= 63.250812754596645
# differential_evolution step 175: f(x)= 63.250812754596645
# differential_evolution step 176: f(x)= 60.45012621523009
# differential_evolution step 177: f(x)= 60.45012621523009
# differential_evolution step 178: f(x)= 60.45012621523009
# differential_evolution step 179: f(x)= 60.45012621523009
# differential_evolution step 180: f(x)= 60.45012621523009
# differential_evolution step 181: f(x)= 60.45012621523009
# differential_evolution step 182: f(x)= 60.45012621523009
# differential_evolution step 183: f(x)= 60.45012621523009
# differential_evolution step 184: f(x)= 59.62460872464725
# differential_evolution step 185: f(x)= 59.62460872464725
# differential_evolution step 186: f(x)= 59.62460872464725
# differential_evolution step 187: f(x)= 59.62460872464725
# differential_evolution step 188: f(x)= 59.62460872464725
# differential_evolution step 189: f(x)= 56.48742736225732
# differential_evolution step 190: f(x)= 56.48742736225732
# differential_evolution step 191: f(x)= 56.48742736225732
# differential_evolution step 192: f(x)= 56.48742736225732
# differential_evolution step 193: f(x)= 56.48742736225732
# differential_evolution step 194: f(x)= 56.48742736225732
# differential_evolution step 195: f(x)= 56.48742736225732
# differential_evolution step 196: f(x)= 54.52314864196275
# differential_evolution step 197: f(x)= 54.52314864196275
# differential_evolution step 198: f(x)= 54.52314864196275
# differential_evolution step 199: f(x)= 54.52314864196275
# differential_evolution step 200: f(x)= 54.52314864196275
# differential_evolution step 201: f(x)= 54.52314864196275
# differential_evolution step 202: f(x)= 54.52314864196275
# differential_evolution step 203: f(x)= 54.52314864196275
# differential_evolution step 204: f(x)= 54.52314864196275
# differential_evolution step 205: f(x)= 54.52314864196275
# differential_evolution step 206: f(x)= 54.52314864196275
# differential_evolution step 207: f(x)= 54.52314864196275
# differential_evolution step 208: f(x)= 54.52314864196275
# differential_evolution step 209: f(x)= 54.52314864196275
# differential_evolution step 210: f(x)= 54.52314864196275
# differential_evolution step 211: f(x)= 54.52314864196275
# differential_evolution step 212: f(x)= 54.52314864196275
# differential_evolution step 213: f(x)= 54.52314864196275
# differential_evolution step 214: f(x)= 54.52314864196275
# differential_evolution step 215: f(x)= 54.52314864196275
# differential_evolution step 216: f(x)= 54.52314864196275
# differential_evolution step 217: f(x)= 52.62229779928232
# differential_evolution step 218: f(x)= 52.62229779928232
# differential_evolution step 219: f(x)= 50.16466881672076
# differential_evolution step 220: f(x)= 50.16466881672076
# differential_evolution step 221: f(x)= 50.16466881672076
# differential_evolution step 222: f(x)= 50.16466881672076
# differential_evolution step 223: f(x)= 50.16466881672076
# differential_evolution step 224: f(x)= 50.16466881672076
# differential_evolution step 225: f(x)= 50.16466881672076
# differential_evolution step 226: f(x)= 50.16466881672076
# differential_evolution step 227: f(x)= 50.16466881672076
# differential_evolution step 228: f(x)= 50.16466881672076
# differential_evolution step 229: f(x)= 50.16466881672076
# differential_evolution step 230: f(x)= 50.16466881672076
# differential_evolution step 231: f(x)= 50.16466881672076
# differential_evolution step 232: f(x)= 50.16466881672076
# differential_evolution step 233: f(x)= 50.16466881672076
# differential_evolution step 234: f(x)= 50.16466881672076
# differential_evolution step 235: f(x)= 50.16466881672076
# differential_evolution step 236: f(x)= 49.666346550209795
# differential_evolution step 237: f(x)= 47.20048273149294
# differential_evolution step 238: f(x)= 46.34337169877793
# differential_evolution step 239: f(x)= 46.34337169877793
# differential_evolution step 240: f(x)= 46.34337169877793
# differential_evolution step 241: f(x)= 46.34337169877793
# differential_evolution step 242: f(x)= 46.34337169877793
# differential_evolution step 243: f(x)= 46.34337169877793
# differential_evolution step 244: f(x)= 46.34337169877793
# differential_evolution step 245: f(x)= 46.34337169877793
# differential_evolution step 246: f(x)= 46.34337169877793
# differential_evolution step 247: f(x)= 46.34337169877793
# differential_evolution step 248: f(x)= 44.577793311154466
# differential_evolution step 249: f(x)= 44.577793311154466
# differential_evolution step 250: f(x)= 44.577793311154466
# differential_evolution step 251: f(x)= 44.577793311154466
# differential_evolution step 252: f(x)= 44.577793311154466
# differential_evolution step 253: f(x)= 44.577793311154466
# differential_evolution step 254: f(x)= 44.577793311154466
# differential_evolution step 255: f(x)= 44.577793311154466
# differential_evolution step 256: f(x)= 44.577793311154466
# differential_evolution step 257: f(x)= 44.577793311154466
# differential_evolution step 258: f(x)= 44.577793311154466
# differential_evolution step 259: f(x)= 44.577793311154466
# differential_evolution step 260: f(x)= 44.577793311154466
# differential_evolution step 261: f(x)= 44.577793311154466
# differential_evolution step 262: f(x)= 44.577793311154466
# differential_evolution step 263: f(x)= 44.577793311154466
# differential_evolution step 264: f(x)= 44.577793311154466
# differential_evolution step 265: f(x)= 43.37901756588019
# differential_evolution step 266: f(x)= 43.37901756588019
# differential_evolution step 267: f(x)= 43.37901756588019
# differential_evolution step 268: f(x)= 43.37901756588019
# differential_evolution step 269: f(x)= 43.37901756588019
# differential_evolution step 270: f(x)= 43.37901756588019
# differential_evolution step 271: f(x)= 43.37901756588019
# differential_evolution step 272: f(x)= 43.37901756588019
# differential_evolution step 273: f(x)= 43.37901756588019
# differential_evolution step 274: f(x)= 43.37901756588019
# differential_evolution step 275: f(x)= 43.37901756588019
# differential_evolution step 276: f(x)= 40.60596547284429
# differential_evolution step 277: f(x)= 40.60596547284429
# differential_evolution step 278: f(x)= 40.60596547284429
# differential_evolution step 279: f(x)= 40.60596547284429
# differential_evolution step 280: f(x)= 40.60596547284429
# differential_evolution step 281: f(x)= 40.60596547284429
# differential_evolution step 282: f(x)= 40.60596547284429
# differential_evolution step 283: f(x)= 40.60596547284429
# differential_evolution step 284: f(x)= 40.60596547284429
# differential_evolution step 285: f(x)= 40.60596547284429
# differential_evolution step 286: f(x)= 40.60596547284429
# differential_evolution step 287: f(x)= 40.60596547284429
# differential_evolution step 288: f(x)= 40.60596547284429
# differential_evolution step 289: f(x)= 40.60596547284429
# differential_evolution step 290: f(x)= 40.60596547284429
# differential_evolution step 291: f(x)= 40.60596547284429
# differential_evolution step 292: f(x)= 40.60596547284429
# differential_evolution step 293: f(x)= 40.60596547284429
# differential_evolution step 294: f(x)= 40.60596547284429
# differential_evolution step 295: f(x)= 40.60596547284429
# differential_evolution step 296: f(x)= 40.60596547284429
# differential_evolution step 297: f(x)= 40.60596547284429
# differential_evolution step 298: f(x)= 40.60596547284429
# differential_evolution step 299: f(x)= 40.60596547284429
# differential_evolution step 300: f(x)= 40.60596547284429
# differential_evolution step 301: f(x)= 40.60596547284429
# differential_evolution step 302: f(x)= 40.60596547284429
# differential_evolution step 303: f(x)= 40.60596547284429
# differential_evolution step 304: f(x)= 40.60596547284429
# differential_evolution step 305: f(x)= 40.60596547284429
# differential_evolution step 306: f(x)= 40.60596547284429
# differential_evolution step 307: f(x)= 40.60596547284429
# differential_evolution step 308: f(x)= 40.60596547284429
# differential_evolution step 309: f(x)= 40.60596547284429
# differential_evolution step 310: f(x)= 40.60596547284429
# differential_evolution step 311: f(x)= 40.60596547284429
# differential_evolution step 312: f(x)= 40.60596547284429
# differential_evolution step 313: f(x)= 40.60596547284429
# differential_evolution step 314: f(x)= 40.60596547284429
# differential_evolution step 315: f(x)= 40.60596547284429
# differential_evolution step 316: f(x)= 40.60596547284429
# differential_evolution step 317: f(x)= 40.60596547284429
# differential_evolution step 318: f(x)= 40.60596547284429
# differential_evolution step 319: f(x)= 40.60596547284429
# differential_evolution step 320: f(x)= 40.60596547284429
# differential_evolution step 321: f(x)= 40.60596547284429
# differential_evolution step 322: f(x)= 40.60596547284429
# differential_evolution step 323: f(x)= 40.60596547284429
# differential_evolution step 324: f(x)= 40.60596547284429
# differential_evolution step 325: f(x)= 40.60596547284429
# differential_evolution step 326: f(x)= 40.60596547284429
# differential_evolution step 327: f(x)= 40.60596547284429
# differential_evolution step 328: f(x)= 40.60596547284429
# differential_evolution step 329: f(x)= 40.60596547284429
# differential_evolution step 330: f(x)= 40.60596547284429
# differential_evolution step 331: f(x)= 40.60596547284429
# differential_evolution step 332: f(x)= 40.60596547284429
# differential_evolution step 333: f(x)= 40.60596547284429
# differential_evolution step 334: f(x)= 40.60596547284429
# differential_evolution step 335: f(x)= 40.60596547284429
# differential_evolution step 336: f(x)= 40.60596547284429
# differential_evolution step 337: f(x)= 40.60596547284429
# differential_evolution step 338: f(x)= 40.60596547284429
# differential_evolution step 339: f(x)= 40.60596547284429
# differential_evolution step 340: f(x)= 40.60596547284429
# differential_evolution step 341: f(x)= 40.60596547284429
# differential_evolution step 342: f(x)= 38.71101540479167
# differential_evolution step 343: f(x)= 38.71101540479167
# differential_evolution step 344: f(x)= 38.71101540479167
# differential_evolution step 345: f(x)= 38.71101540479167
# differential_evolution step 346: f(x)= 38.71101540479167
# differential_evolution step 347: f(x)= 38.71101540479167
# differential_evolution step 348: f(x)= 38.71101540479167
# differential_evolution step 349: f(x)= 38.71101540479167
# differential_evolution step 350: f(x)= 38.71101540479167
# differential_evolution step 351: f(x)= 38.71101540479167
# differential_evolution step 352: f(x)= 38.71101540479167
# differential_evolution step 353: f(x)= 38.71101540479167
# differential_evolution step 354: f(x)= 38.71101540479167
# differential_evolution step 355: f(x)= 38.71101540479167
# differential_evolution step 356: f(x)= 38.71101540479167
# differential_evolution step 357: f(x)= 38.71101540479167
# differential_evolution step 358: f(x)= 38.71101540479167
# differential_evolution step 359: f(x)= 38.71101540479167
# differential_evolution step 360: f(x)= 38.71101540479167
# differential_evolution step 361: f(x)= 38.71101540479167
# differential_evolution step 362: f(x)= 38.71101540479167
# differential_evolution step 363: f(x)= 38.71101540479167
# differential_evolution step 364: f(x)= 38.71101540479167
# differential_evolution step 365: f(x)= 38.71101540479167
# differential_evolution step 366: f(x)= 38.71101540479167
# differential_evolution step 367: f(x)= 38.71101540479167
# differential_evolution step 368: f(x)= 38.71101540479167
# differential_evolution step 369: f(x)= 38.71101540479167
# differential_evolution step 370: f(x)= 38.71101540479167
# differential_evolution step 371: f(x)= 38.71101540479167
# differential_evolution step 372: f(x)= 38.71101540479167
# differential_evolution step 373: f(x)= 38.25790605656588
# differential_evolution step 374: f(x)= 38.25790605656588
# differential_evolution step 375: f(x)= 38.25790605656588
# differential_evolution step 376: f(x)= 38.25790605656588
# differential_evolution step 377: f(x)= 38.25790605656588
# differential_evolution step 378: f(x)= 38.25790605656588
# differential_evolution step 379: f(x)= 38.25790605656588
# differential_evolution step 380: f(x)= 38.25790605656588
# differential_evolution step 381: f(x)= 38.25790605656588
# differential_evolution step 382: f(x)= 38.25790605656588
# differential_evolution step 383: f(x)= 38.25790605656588
# differential_evolution step 384: f(x)= 38.25790605656588
# differential_evolution step 385: f(x)= 38.25790605656588
# differential_evolution step 386: f(x)= 38.25790605656588
# differential_evolution step 387: f(x)= 38.25790605656588
# differential_evolution step 388: f(x)= 38.25790605656588
# differential_evolution step 389: f(x)= 38.25790605656588
# differential_evolution step 390: f(x)= 38.25790605656588
# differential_evolution step 391: f(x)= 38.25790605656588
# differential_evolution step 392: f(x)= 38.25790605656588
# differential_evolution step 393: f(x)= 38.25790605656588
# differential_evolution step 394: f(x)= 38.25790605656588
# differential_evolution step 395: f(x)= 37.75121565122913
# differential_evolution step 396: f(x)= 37.75121565122913
# differential_evolution step 397: f(x)= 37.75121565122913
# differential_evolution step 398: f(x)= 37.75121565122913
# differential_evolution step 399: f(x)= 37.66977939475437
# differential_evolution step 400: f(x)= 37.66977939475437
# differential_evolution step 401: f(x)= 35.99935597726338
# differential_evolution step 402: f(x)= 35.99935597726338
# differential_evolution step 403: f(x)= 35.99935597726338
# differential_evolution step 404: f(x)= 35.99935597726338
# differential_evolution step 405: f(x)= 35.99935597726338
# differential_evolution step 406: f(x)= 35.99935597726338
# differential_evolution step 407: f(x)= 35.99935597726338
# differential_evolution step 408: f(x)= 35.99935597726338
# differential_evolution step 409: f(x)= 35.99935597726338
# differential_evolution step 410: f(x)= 35.99935597726338
# differential_evolution step 411: f(x)= 35.99935597726338
# differential_evolution step 412: f(x)= 35.99935597726338
# differential_evolution step 413: f(x)= 35.99935597726338
# differential_evolution step 414: f(x)= 35.99935597726338
# differential_evolution step 415: f(x)= 35.99935597726338
# differential_evolution step 416: f(x)= 35.99935597726338
# differential_evolution step 417: f(x)= 35.99935597726338
# differential_evolution step 418: f(x)= 35.99935597726338
# differential_evolution step 419: f(x)= 35.99935597726338
# differential_evolution step 420: f(x)= 35.937308379476974
# differential_evolution step 421: f(x)= 35.937308379476974
# differential_evolution step 422: f(x)= 35.937308379476974
# differential_evolution step 423: f(x)= 35.937308379476974
# differential_evolution step 424: f(x)= 35.238034720291076
# differential_evolution step 425: f(x)= 35.238034720291076
# differential_evolution step 426: f(x)= 35.238034720291076
# differential_evolution step 427: f(x)= 35.238034720291076
# differential_evolution step 428: f(x)= 35.238034720291076
# differential_evolution step 429: f(x)= 35.238034720291076
# differential_evolution step 430: f(x)= 35.238034720291076
# differential_evolution step 431: f(x)= 35.238034720291076
# differential_evolution step 432: f(x)= 35.238034720291076
# differential_evolution step 433: f(x)= 35.238034720291076
# differential_evolution step 434: f(x)= 35.238034720291076
# differential_evolution step 435: f(x)= 35.238034720291076
# differential_evolution step 436: f(x)= 35.238034720291076
# differential_evolution step 437: f(x)= 35.238034720291076
# differential_evolution step 438: f(x)= 35.238034720291076
# differential_evolution step 439: f(x)= 35.238034720291076
# differential_evolution step 440: f(x)= 35.238034720291076
# differential_evolution step 441: f(x)= 34.71267472557124
# differential_evolution step 442: f(x)= 34.71267472557124
# differential_evolution step 443: f(x)= 34.71267472557124
# differential_evolution step 444: f(x)= 34.71267472557124
# differential_evolution step 445: f(x)= 34.71267472557124
# differential_evolution step 446: f(x)= 34.71267472557124
# differential_evolution step 447: f(x)= 34.71267472557124
# differential_evolution step 448: f(x)= 34.71267472557124
# differential_evolution step 449: f(x)= 34.71267472557124
# differential_evolution step 450: f(x)= 34.71267472557124
# differential_evolution step 451: f(x)= 34.71267472557124
# differential_evolution step 452: f(x)= 34.71267472557124
# differential_evolution step 453: f(x)= 34.71267472557124
# differential_evolution step 454: f(x)= 34.71267472557124
# differential_evolution step 455: f(x)= 34.71267472557124
# differential_evolution step 456: f(x)= 34.71267472557124
# differential_evolution step 457: f(x)= 34.71267472557124
# differential_evolution step 458: f(x)= 34.71267472557124
# differential_evolution step 459: f(x)= 34.71267472557124
# differential_evolution step 460: f(x)= 34.71267472557124
# differential_evolution step 461: f(x)= 34.71267472557124
# differential_evolution step 462: f(x)= 34.71267472557124
# differential_evolution step 463: f(x)= 34.71267472557124
# differential_evolution step 464: f(x)= 34.71267472557124
# differential_evolution step 465: f(x)= 34.71267472557124
# differential_evolution step 466: f(x)= 34.71267472557124
# differential_evolution step 467: f(x)= 34.71267472557124
# differential_evolution step 468: f(x)= 34.71267472557124
# differential_evolution step 469: f(x)= 34.71267472557124
# differential_evolution step 470: f(x)= 34.71267472557124
# differential_evolution step 471: f(x)= 34.71267472557124
# differential_evolution step 472: f(x)= 34.71267472557124
# differential_evolution step 473: f(x)= 34.71267472557124
# differential_evolution step 474: f(x)= 34.71267472557124
# differential_evolution step 475: f(x)= 34.71267472557124
# differential_evolution step 476: f(x)= 34.71267472557124
# differential_evolution step 477: f(x)= 34.71267472557124
# differential_evolution step 478: f(x)= 34.71267472557124
# differential_evolution step 479: f(x)= 34.71267472557124
# differential_evolution step 480: f(x)= 34.71267472557124
# differential_evolution step 481: f(x)= 34.71267472557124
# differential_evolution step 482: f(x)= 34.71267472557124
# differential_evolution step 483: f(x)= 34.19202353798643
# differential_evolution step 484: f(x)= 34.19202353798643
# differential_evolution step 485: f(x)= 34.19202353798643
# differential_evolution step 486: f(x)= 34.19202353798643
# differential_evolution step 487: f(x)= 33.76692430608224
# differential_evolution step 488: f(x)= 33.76692430608224
# differential_evolution step 489: f(x)= 33.76692430608224
# differential_evolution step 490: f(x)= 33.76692430608224
# differential_evolution step 491: f(x)= 33.76692430608224
# differential_evolution step 492: f(x)= 33.76692430608224
# differential_evolution step 493: f(x)= 33.76692430608224
# differential_evolution step 494: f(x)= 33.76692430608224
# differential_evolution step 495: f(x)= 33.76692430608224
# differential_evolution step 496: f(x)= 33.76692430608224
# differential_evolution step 497: f(x)= 33.76692430608224
# differential_evolution step 498: f(x)= 33.195526497899266
# differential_evolution step 499: f(x)= 33.195526497899266
# differential_evolution step 500: f(x)= 33.195526497899266
# differential_evolution step 501: f(x)= 33.195526497899266
# differential_evolution step 502: f(x)= 33.195526497899266
# differential_evolution step 503: f(x)= 33.195526497899266
# differential_evolution step 504: f(x)= 33.195526497899266
# differential_evolution step 505: f(x)= 33.195526497899266
# differential_evolution step 506: f(x)= 33.195526497899266
# differential_evolution step 507: f(x)= 33.195526497899266
# differential_evolution step 508: f(x)= 33.195526497899266
# differential_evolution step 509: f(x)= 33.195526497899266
# differential_evolution step 510: f(x)= 33.195526497899266
# differential_evolution step 511: f(x)= 33.195526497899266
# differential_evolution step 512: f(x)= 33.195526497899266
# differential_evolution step 513: f(x)= 33.195526497899266
# differential_evolution step 514: f(x)= 33.195526497899266
# differential_evolution step 515: f(x)= 33.195526497899266
# differential_evolution step 516: f(x)= 33.195526497899266
# differential_evolution step 517: f(x)= 33.195526497899266
# differential_evolution step 518: f(x)= 33.195526497899266
# differential_evolution step 519: f(x)= 33.195526497899266
# differential_evolution step 520: f(x)= 32.05212259988634
# differential_evolution step 521: f(x)= 32.05212259988634
# differential_evolution step 522: f(x)= 32.05212259988634
# differential_evolution step 523: f(x)= 32.05212259988634
# differential_evolution step 524: f(x)= 32.05212259988634
# differential_evolution step 525: f(x)= 32.05212259988634
# differential_evolution step 526: f(x)= 32.05212259988634
# differential_evolution step 527: f(x)= 32.05212259988634
# differential_evolution step 528: f(x)= 32.05212259988634
# differential_evolution step 529: f(x)= 32.05212259988634
# differential_evolution step 530: f(x)= 32.05212259988634
# differential_evolution step 531: f(x)= 32.05212259988634
# differential_evolution step 532: f(x)= 32.05212259988634
# differential_evolution step 533: f(x)= 32.05212259988634
# differential_evolution step 534: f(x)= 32.05212259988634
# differential_evolution step 535: f(x)= 32.05212259988634
# differential_evolution step 536: f(x)= 32.05212259988634
# differential_evolution step 537: f(x)= 32.05212259988634
# differential_evolution step 538: f(x)= 32.05212259988634
# differential_evolution step 539: f(x)= 32.05212259988634
# differential_evolution step 540: f(x)= 32.05212259988634
# differential_evolution step 541: f(x)= 32.05212259988634
# differential_evolution step 542: f(x)= 32.05212259988634
# differential_evolution step 543: f(x)= 32.05212259988634
# differential_evolution step 544: f(x)= 32.05212259988634
# differential_evolution step 545: f(x)= 32.05212259988634
# differential_evolution step 546: f(x)= 32.05212259988634
# differential_evolution step 547: f(x)= 32.05212259988634
# differential_evolution step 548: f(x)= 31.967744368680684
# differential_evolution step 549: f(x)= 31.967744368680684
# differential_evolution step 550: f(x)= 31.967744368680684
# differential_evolution step 551: f(x)= 31.967744368680684
# differential_evolution step 552: f(x)= 31.967744368680684
# differential_evolution step 553: f(x)= 31.967744368680684
# differential_evolution step 554: f(x)= 31.967744368680684
# differential_evolution step 555: f(x)= 31.967744368680684
# differential_evolution step 556: f(x)= 31.967744368680684
# differential_evolution step 557: f(x)= 31.967744368680684
# differential_evolution step 558: f(x)= 31.967744368680684
# differential_evolution step 559: f(x)= 31.967744368680684
# differential_evolution step 560: f(x)= 31.270422592715782
# differential_evolution step 561: f(x)= 31.270422592715782
# differential_evolution step 562: f(x)= 31.270422592715782
# differential_evolution step 563: f(x)= 31.270422592715782
# differential_evolution step 564: f(x)= 31.270422592715782
# differential_evolution step 565: f(x)= 31.270422592715782
# differential_evolution step 566: f(x)= 31.270422592715782
# differential_evolution step 567: f(x)= 31.270422592715782
# differential_evolution step 568: f(x)= 31.270422592715782
# differential_evolution step 569: f(x)= 31.270422592715782
# differential_evolution step 570: f(x)= 31.270422592715782
# differential_evolution step 571: f(x)= 31.270422592715782
# differential_evolution step 572: f(x)= 31.270422592715782
# differential_evolution step 573: f(x)= 31.270422592715782
# differential_evolution step 574: f(x)= 31.270422592715782
# differential_evolution step 575: f(x)= 31.270422592715782
# differential_evolution step 576: f(x)= 31.270422592715782
# differential_evolution step 577: f(x)= 31.270422592715782
# differential_evolution step 578: f(x)= 31.270422592715782
# differential_evolution step 579: f(x)= 31.270422592715782
# differential_evolution step 580: f(x)= 31.270422592715782
# differential_evolution step 581: f(x)= 31.270422592715782
# differential_evolution step 582: f(x)= 31.270422592715782
# differential_evolution step 583: f(x)= 31.270422592715782
# differential_evolution step 584: f(x)= 31.270422592715782
# differential_evolution step 585: f(x)= 31.270422592715782
# differential_evolution step 586: f(x)= 31.270422592715782
# differential_evolution step 587: f(x)= 31.270422592715782
# differential_evolution step 588: f(x)= 31.270422592715782
# differential_evolution step 589: f(x)= 31.270422592715782
# differential_evolution step 590: f(x)= 31.270422592715782
# differential_evolution step 591: f(x)= 31.270422592715782
# differential_evolution step 592: f(x)= 31.270422592715782
# differential_evolution step 593: f(x)= 31.270422592715782
# differential_evolution step 594: f(x)= 31.270422592715782
# differential_evolution step 595: f(x)= 31.270422592715782
# differential_evolution step 596: f(x)= 31.270422592715782
# differential_evolution step 597: f(x)= 31.270422592715782
# differential_evolution step 598: f(x)= 31.270422592715782
# differential_evolution step 599: f(x)= 31.270422592715782
# differential_evolution step 600: f(x)= 31.270422592715782
# differential_evolution step 601: f(x)= 31.270422592715782
# differential_evolution step 602: f(x)= 31.270422592715782
# differential_evolution step 603: f(x)= 30.775153045275673
# differential_evolution step 604: f(x)= 30.775153045275673
# differential_evolution step 605: f(x)= 30.775153045275673
# differential_evolution step 606: f(x)= 30.775153045275673
# differential_evolution step 607: f(x)= 30.775153045275673
# differential_evolution step 608: f(x)= 30.775153045275673
# differential_evolution step 609: f(x)= 30.775153045275673
# differential_evolution step 610: f(x)= 30.775153045275673
# differential_evolution step 611: f(x)= 30.707028768132464
# differential_evolution step 612: f(x)= 30.707028768132464
# differential_evolution step 613: f(x)= 30.707028768132464
# differential_evolution step 614: f(x)= 30.707028768132464
# differential_evolution step 615: f(x)= 30.707028768132464
# differential_evolution step 616: f(x)= 30.707028768132464
# differential_evolution step 617: f(x)= 30.707028768132464
# differential_evolution step 618: f(x)= 30.707028768132464
# differential_evolution step 619: f(x)= 30.707028768132464
# differential_evolution step 620: f(x)= 30.707028768132464
# differential_evolution step 621: f(x)= 30.707028768132464
# differential_evolution step 622: f(x)= 30.707028768132464
# differential_evolution step 623: f(x)= 30.707028768132464
# differential_evolution step 624: f(x)= 30.707028768132464
# differential_evolution step 625: f(x)= 30.707028768132464
# differential_evolution step 626: f(x)= 30.707028768132464
# differential_evolution step 627: f(x)= 30.707028768132464
# differential_evolution step 628: f(x)= 30.707028768132464
# differential_evolution step 629: f(x)= 30.008225675494707
# differential_evolution step 630: f(x)= 30.008225675494707
# differential_evolution step 631: f(x)= 30.008225675494707
# differential_evolution step 632: f(x)= 30.008225675494707
# differential_evolution step 633: f(x)= 30.008225675494707
# differential_evolution step 634: f(x)= 30.008225675494707
# differential_evolution step 635: f(x)= 30.008225675494707
# differential_evolution step 636: f(x)= 30.008225675494707
# differential_evolution step 637: f(x)= 30.008225675494707
# differential_evolution step 638: f(x)= 30.008225675494707
# differential_evolution step 639: f(x)= 30.008225675494707
# differential_evolution step 640: f(x)= 30.008225675494707
# differential_evolution step 641: f(x)= 30.008225675494707
# differential_evolution step 642: f(x)= 30.008225675494707
# differential_evolution step 643: f(x)= 30.008225675494707
# differential_evolution step 644: f(x)= 30.008225675494707
# differential_evolution step 645: f(x)= 30.008225675494707
# differential_evolution step 646: f(x)= 30.008225675494707
# differential_evolution step 647: f(x)= 30.008225675494707
# differential_evolution step 648: f(x)= 30.008225675494707
# differential_evolution step 649: f(x)= 30.008225675494707
# differential_evolution step 650: f(x)= 30.008225675494707
# differential_evolution step 651: f(x)= 30.008225675494707
# differential_evolution step 652: f(x)= 30.008225675494707
# differential_evolution step 653: f(x)= 30.008225675494707
# differential_evolution step 654: f(x)= 30.008225675494707
# differential_evolution step 655: f(x)= 30.008225675494707
# differential_evolution step 656: f(x)= 30.008225675494707
# differential_evolution step 657: f(x)= 30.008225675494707
# differential_evolution step 658: f(x)= 30.008225675494707
# differential_evolution step 659: f(x)= 30.008225675494707
# differential_evolution step 660: f(x)= 30.008225675494707
# differential_evolution step 661: f(x)= 30.008225675494707
# differential_evolution step 662: f(x)= 30.008225675494707
# differential_evolution step 663: f(x)= 30.008225675494707
# differential_evolution step 664: f(x)= 30.008225675494707
# differential_evolution step 665: f(x)= 30.008225675494707
# differential_evolution step 666: f(x)= 30.008225675494707
# differential_evolution step 667: f(x)= 30.008225675494707
# differential_evolution step 668: f(x)= 30.008225675494707
# differential_evolution step 669: f(x)= 30.008225675494707
# differential_evolution step 670: f(x)= 30.008225675494707
# differential_evolution step 671: f(x)= 30.008225675494707
# differential_evolution step 672: f(x)= 30.008225675494707
# differential_evolution step 673: f(x)= 30.008225675494707
# differential_evolution step 674: f(x)= 30.008225675494707
# differential_evolution step 675: f(x)= 30.008225675494707
# differential_evolution step 676: f(x)= 30.008225675494707
# differential_evolution step 677: f(x)= 29.99693797583836
# differential_evolution step 678: f(x)= 29.99693797583836
# differential_evolution step 679: f(x)= 29.99693797583836
# differential_evolution step 680: f(x)= 29.99693797583836
# differential_evolution step 681: f(x)= 29.99693797583836
# differential_evolution step 682: f(x)= 29.99693797583836
# differential_evolution step 683: f(x)= 29.99693797583836
# differential_evolution step 684: f(x)= 29.99693797583836
# differential_evolution step 685: f(x)= 29.99693797583836
# differential_evolution step 686: f(x)= 29.99693797583836
# differential_evolution step 687: f(x)= 29.99693797583836
# differential_evolution step 688: f(x)= 29.99693797583836
# differential_evolution step 689: f(x)= 29.99693797583836
# differential_evolution step 690: f(x)= 29.99693797583836
# differential_evolution step 691: f(x)= 29.99693797583836
# differential_evolution step 692: f(x)= 29.99693797583836
# differential_evolution step 693: f(x)= 29.99693797583836
# differential_evolution step 694: f(x)= 29.99693797583836
# differential_evolution step 695: f(x)= 29.99693797583836
# differential_evolution step 696: f(x)= 29.928438242379716
# differential_evolution step 697: f(x)= 29.2992278738921
# differential_evolution step 698: f(x)= 29.2992278738921
# differential_evolution step 699: f(x)= 29.2992278738921
# differential_evolution step 700: f(x)= 29.2992278738921
# differential_evolution step 701: f(x)= 29.2992278738921
# differential_evolution step 702: f(x)= 29.2992278738921
# differential_evolution step 703: f(x)= 29.2992278738921
# differential_evolution step 704: f(x)= 29.2992278738921
# differential_evolution step 705: f(x)= 29.2992278738921
# differential_evolution step 706: f(x)= 29.2992278738921
# differential_evolution step 707: f(x)= 29.2992278738921
# differential_evolution step 708: f(x)= 29.2992278738921
# differential_evolution step 709: f(x)= 29.2992278738921
# differential_evolution step 710: f(x)= 28.968969473164815
# differential_evolution step 711: f(x)= 28.968969473164815
# differential_evolution step 712: f(x)= 28.968969473164815
# differential_evolution step 713: f(x)= 28.968969473164815
# differential_evolution step 714: f(x)= 28.968969473164815
# differential_evolution step 715: f(x)= 28.968969473164815
# differential_evolution step 716: f(x)= 28.968969473164815
# differential_evolution step 717: f(x)= 28.968969473164815
# differential_evolution step 718: f(x)= 28.968969473164815
# differential_evolution step 719: f(x)= 28.968969473164815
# differential_evolution step 720: f(x)= 28.968969473164815
# differential_evolution step 721: f(x)= 28.968969473164815
# differential_evolution step 722: f(x)= 28.968969473164815
# differential_evolution step 723: f(x)= 28.968969473164815
# differential_evolution step 724: f(x)= 28.968969473164815
# differential_evolution step 725: f(x)= 28.968969473164815
# differential_evolution step 726: f(x)= 28.968969473164815
# differential_evolution step 727: f(x)= 28.968969473164815
# differential_evolution step 728: f(x)= 28.968969473164815
# differential_evolution step 729: f(x)= 28.968969473164815
# differential_evolution step 730: f(x)= 28.968969473164815
# differential_evolution step 731: f(x)= 28.968969473164815
# differential_evolution step 732: f(x)= 28.968969473164815
# differential_evolution step 733: f(x)= 28.968969473164815
# differential_evolution step 734: f(x)= 28.968969473164815
# differential_evolution step 735: f(x)= 28.968969473164815
# differential_evolution step 736: f(x)= 28.968969473164815
# differential_evolution step 737: f(x)= 28.968969473164815
# differential_evolution step 738: f(x)= 28.968969473164815
# differential_evolution step 739: f(x)= 28.968969473164815
# differential_evolution step 740: f(x)= 28.968969473164815
# differential_evolution step 741: f(x)= 28.968969473164815
# differential_evolution step 742: f(x)= 28.968969473164815
# differential_evolution step 743: f(x)= 28.968969473164815
# differential_evolution step 744: f(x)= 28.968969473164815
# differential_evolution step 745: f(x)= 28.968969473164815
# differential_evolution step 746: f(x)= 28.968969473164815
# differential_evolution step 747: f(x)= 28.968969473164815
# differential_evolution step 748: f(x)= 28.968969473164815
# differential_evolution step 749: f(x)= 28.968969473164815
# differential_evolution step 750: f(x)= 28.968969473164815
# differential_evolution step 751: f(x)= 28.968969473164815
# differential_evolution step 752: f(x)= 28.968969473164815
# differential_evolution step 753: f(x)= 28.968969473164815
# differential_evolution step 754: f(x)= 28.968969473164815
# differential_evolution step 755: f(x)= 28.968969473164815
# differential_evolution step 756: f(x)= 28.968969473164815
# differential_evolution step 757: f(x)= 28.968969473164815
# differential_evolution step 758: f(x)= 28.968969473164815
# differential_evolution step 759: f(x)= 28.968969473164815
# differential_evolution step 760: f(x)= 28.968969473164815
# differential_evolution step 761: f(x)= 28.968969473164815
# differential_evolution step 762: f(x)= 28.968969473164815
# differential_evolution step 763: f(x)= 28.968969473164815
# differential_evolution step 764: f(x)= 28.968969473164815
# differential_evolution step 765: f(x)= 28.968969473164815
# differential_evolution step 766: f(x)= 28.968969473164815
# differential_evolution step 767: f(x)= 28.968969473164815
# differential_evolution step 768: f(x)= 28.968969473164815
# differential_evolution step 769: f(x)= 28.968969473164815
# differential_evolution step 770: f(x)= 28.968969473164815
# differential_evolution step 771: f(x)= 28.968969473164815
# differential_evolution step 772: f(x)= 28.968969473164815
# differential_evolution step 773: f(x)= 28.968969473164815
# differential_evolution step 774: f(x)= 28.968969473164815
# differential_evolution step 775: f(x)= 28.968969473164815
# differential_evolution step 776: f(x)= 28.968969473164815
# differential_evolution step 777: f(x)= 28.968969473164815
# differential_evolution step 778: f(x)= 28.968969473164815
# differential_evolution step 779: f(x)= 28.968969473164815
# differential_evolution step 780: f(x)= 28.968969473164815
# differential_evolution step 781: f(x)= 28.968969473164815
# differential_evolution step 782: f(x)= 28.968969473164815
# differential_evolution step 783: f(x)= 28.968969473164815
# differential_evolution step 784: f(x)= 28.968969473164815
# differential_evolution step 785: f(x)= 28.21001354710757
# differential_evolution step 786: f(x)= 28.21001354710757
# differential_evolution step 787: f(x)= 28.21001354710757
# differential_evolution step 788: f(x)= 28.21001354710757
# differential_evolution step 789: f(x)= 28.21001354710757
# differential_evolution step 790: f(x)= 28.21001354710757
# differential_evolution step 791: f(x)= 28.21001354710757
# differential_evolution step 792: f(x)= 28.21001354710757
# differential_evolution step 793: f(x)= 28.21001354710757
# differential_evolution step 794: f(x)= 28.21001354710757
# differential_evolution step 795: f(x)= 28.21001354710757
# differential_evolution step 796: f(x)= 28.21001354710757
# differential_evolution step 797: f(x)= 28.21001354710757
# differential_evolution step 798: f(x)= 28.21001354710757
# differential_evolution step 799: f(x)= 28.21001354710757
# differential_evolution step 800: f(x)= 28.21001354710757
# differential_evolution step 801: f(x)= 28.21001354710757
# differential_evolution step 802: f(x)= 28.21001354710757
# differential_evolution step 803: f(x)= 28.21001354710757
# differential_evolution step 804: f(x)= 28.21001354710757
# differential_evolution step 805: f(x)= 28.21001354710757
# differential_evolution step 806: f(x)= 28.21001354710757
# differential_evolution step 807: f(x)= 28.21001354710757
# differential_evolution step 808: f(x)= 28.21001354710757
# differential_evolution step 809: f(x)= 28.21001354710757
# differential_evolution step 810: f(x)= 28.21001354710757
# differential_evolution step 811: f(x)= 28.21001354710757
# differential_evolution step 812: f(x)= 28.21001354710757
# differential_evolution step 813: f(x)= 28.21001354710757
# differential_evolution step 814: f(x)= 28.21001354710757
# differential_evolution step 815: f(x)= 28.21001354710757
# differential_evolution step 816: f(x)= 28.21001354710757
# differential_evolution step 817: f(x)= 28.21001354710757
# differential_evolution step 818: f(x)= 28.21001354710757
# differential_evolution step 819: f(x)= 28.21001354710757
# differential_evolution step 820: f(x)= 28.21001354710757
# differential_evolution step 821: f(x)= 28.21001354710757
# differential_evolution step 822: f(x)= 28.21001354710757
# differential_evolution step 823: f(x)= 28.21001354710757
# differential_evolution step 824: f(x)= 28.21001354710757
# differential_evolution step 825: f(x)= 28.21001354710757
# differential_evolution step 826: f(x)= 28.21001354710757
# differential_evolution step 827: f(x)= 28.21001354710757
# differential_evolution step 828: f(x)= 28.21001354710757
# differential_evolution step 829: f(x)= 28.21001354710757
# differential_evolution step 830: f(x)= 28.21001354710757
# differential_evolution step 831: f(x)= 28.21001354710757
# differential_evolution step 832: f(x)= 28.21001354710757
# differential_evolution step 833: f(x)= 28.21001354710757
# differential_evolution step 834: f(x)= 28.21001354710757
# differential_evolution step 835: f(x)= 28.21001354710757
# differential_evolution step 836: f(x)= 28.21001354710757
# differential_evolution step 837: f(x)= 28.21001354710757
# differential_evolution step 838: f(x)= 28.21001354710757
# differential_evolution step 839: f(x)= 28.21001354710757
# differential_evolution step 840: f(x)= 28.21001354710757
# differential_evolution step 841: f(x)= 28.21001354710757
# differential_evolution step 842: f(x)= 28.21001354710757
# differential_evolution step 843: f(x)= 28.21001354710757
# differential_evolution step 844: f(x)= 28.21001354710757
# differential_evolution step 845: f(x)= 28.21001354710757
# differential_evolution step 846: f(x)= 28.21001354710757
# differential_evolution step 847: f(x)= 28.21001354710757
# differential_evolution step 848: f(x)= 28.21001354710757
# differential_evolution step 849: f(x)= 28.21001354710757
# differential_evolution step 850: f(x)= 28.21001354710757
# differential_evolution step 851: f(x)= 28.21001354710757
# differential_evolution step 852: f(x)= 28.21001354710757
# differential_evolution step 853: f(x)= 28.21001354710757
# differential_evolution step 854: f(x)= 28.21001354710757
# differential_evolution step 855: f(x)= 28.21001354710757
# differential_evolution step 856: f(x)= 28.21001354710757
# differential_evolution step 857: f(x)= 28.21001354710757
# differential_evolution step 858: f(x)= 28.21001354710757
# differential_evolution step 859: f(x)= 28.21001354710757
# differential_evolution step 860: f(x)= 28.21001354710757
# differential_evolution step 861: f(x)= 28.21001354710757
# differential_evolution step 862: f(x)= 28.21001354710757
# differential_evolution step 863: f(x)= 28.21001354710757
# differential_evolution step 864: f(x)= 28.21001354710757
# differential_evolution step 865: f(x)= 28.21001354710757
# differential_evolution step 866: f(x)= 28.21001354710757
# differential_evolution step 867: f(x)= 28.21001354710757
# differential_evolution step 868: f(x)= 28.21001354710757
# differential_evolution step 869: f(x)= 28.21001354710757
# differential_evolution step 870: f(x)= 28.21001354710757
# differential_evolution step 871: f(x)= 28.21001354710757
# differential_evolution step 872: f(x)= 28.21001354710757
# differential_evolution step 873: f(x)= 28.21001354710757
# differential_evolution step 874: f(x)= 28.21001354710757
# differential_evolution step 875: f(x)= 28.21001354710757
# differential_evolution step 876: f(x)= 28.21001354710757
# differential_evolution step 877: f(x)= 28.21001354710757
# differential_evolution step 878: f(x)= 28.21001354710757
# differential_evolution step 879: f(x)= 28.21001354710757
# differential_evolution step 880: f(x)= 28.21001354710757
# differential_evolution step 881: f(x)= 28.21001354710757
# differential_evolution step 882: f(x)= 28.21001354710757
# differential_evolution step 883: f(x)= 28.21001354710757
# differential_evolution step 884: f(x)= 28.21001354710757
# differential_evolution step 885: f(x)= 28.21001354710757
# differential_evolution step 886: f(x)= 28.21001354710757
# differential_evolution step 887: f(x)= 28.21001354710757
# differential_evolution step 888: f(x)= 28.21001354710757
# differential_evolution step 889: f(x)= 28.21001354710757
# differential_evolution step 890: f(x)= 28.075822470118233
# differential_evolution step 891: f(x)= 28.075822470118233
# differential_evolution step 892: f(x)= 28.075822470118233
# differential_evolution step 893: f(x)= 28.075822470118233
# differential_evolution step 894: f(x)= 28.075822470118233
# differential_evolution step 895: f(x)= 28.075822470118233
# differential_evolution step 896: f(x)= 28.075822470118233
# differential_evolution step 897: f(x)= 27.981742074976534
# differential_evolution step 898: f(x)= 27.981742074976534
# differential_evolution step 899: f(x)= 27.34896331534607
# differential_evolution step 900: f(x)= 27.34896331534607
# differential_evolution step 901: f(x)= 27.34896331534607
# differential_evolution step 902: f(x)= 27.34896331534607
# differential_evolution step 903: f(x)= 27.34896331534607
# differential_evolution step 904: f(x)= 27.34896331534607
# differential_evolution step 905: f(x)= 27.34896331534607
# differential_evolution step 906: f(x)= 27.34896331534607
# differential_evolution step 907: f(x)= 27.34896331534607
# differential_evolution step 908: f(x)= 27.34896331534607
# differential_evolution step 909: f(x)= 27.34896331534607
# differential_evolution step 910: f(x)= 27.34896331534607
# differential_evolution step 911: f(x)= 27.34896331534607
# differential_evolution step 912: f(x)= 27.34896331534607
# differential_evolution step 913: f(x)= 27.34896331534607
# differential_evolution step 914: f(x)= 27.34896331534607
# differential_evolution step 915: f(x)= 27.34896331534607
# differential_evolution step 916: f(x)= 27.34896331534607
# differential_evolution step 917: f(x)= 27.34896331534607
# differential_evolution step 918: f(x)= 27.34896331534607
# differential_evolution step 919: f(x)= 27.34896331534607
# differential_evolution step 920: f(x)= 27.34896331534607
# differential_evolution step 921: f(x)= 27.34896331534607
# differential_evolution step 922: f(x)= 27.34896331534607
# differential_evolution step 923: f(x)= 27.34896331534607
# differential_evolution step 924: f(x)= 27.34896331534607
# differential_evolution step 925: f(x)= 27.34896331534607
# differential_evolution step 926: f(x)= 27.34896331534607
# differential_evolution step 927: f(x)= 27.34896331534607
# differential_evolution step 928: f(x)= 27.34896331534607
# differential_evolution step 929: f(x)= 27.34896331534607
# differential_evolution step 930: f(x)= 27.34896331534607
# differential_evolution step 931: f(x)= 27.34896331534607
# differential_evolution step 932: f(x)= 27.34896331534607
# differential_evolution step 933: f(x)= 27.34896331534607
# differential_evolution step 934: f(x)= 27.34896331534607
# differential_evolution step 935: f(x)= 27.34896331534607
# differential_evolution step 936: f(x)= 27.34896331534607
# differential_evolution step 937: f(x)= 27.34896331534607
# differential_evolution step 938: f(x)= 27.34896331534607
# differential_evolution step 939: f(x)= 27.34896331534607
# differential_evolution step 940: f(x)= 26.405789973184252
# differential_evolution step 941: f(x)= 26.405789973184252
# differential_evolution step 942: f(x)= 26.405789973184252
# differential_evolution step 943: f(x)= 26.405789973184252
# differential_evolution step 944: f(x)= 26.30557192807111
# differential_evolution step 945: f(x)= 26.30557192807111
# differential_evolution step 946: f(x)= 26.30557192807111
# differential_evolution step 947: f(x)= 26.30557192807111
# differential_evolution step 948: f(x)= 26.30557192807111
# differential_evolution step 949: f(x)= 26.30557192807111
# differential_evolution step 950: f(x)= 26.30557192807111
# differential_evolution step 951: f(x)= 26.30557192807111
# differential_evolution step 952: f(x)= 26.30557192807111
# differential_evolution step 953: f(x)= 26.30557192807111
# differential_evolution step 954: f(x)= 26.30557192807111
# differential_evolution step 955: f(x)= 26.30557192807111
# differential_evolution step 956: f(x)= 26.30557192807111
# differential_evolution step 957: f(x)= 26.30557192807111
# differential_evolution step 958: f(x)= 26.30557192807111
# differential_evolution step 959: f(x)= 26.30557192807111
# differential_evolution step 960: f(x)= 26.30557192807111
# differential_evolution step 961: f(x)= 25.61713477207707
# differential_evolution step 962: f(x)= 25.61713477207707
# differential_evolution step 963: f(x)= 25.61713477207707
# differential_evolution step 964: f(x)= 25.61713477207707
# differential_evolution step 965: f(x)= 25.61713477207707
# differential_evolution step 966: f(x)= 25.61713477207707
# differential_evolution step 967: f(x)= 25.61713477207707
# differential_evolution step 968: f(x)= 25.61713477207707
# differential_evolution step 969: f(x)= 25.61713477207707
# differential_evolution step 970: f(x)= 25.61713477207707
# differential_evolution step 971: f(x)= 25.61713477207707
# differential_evolution step 972: f(x)= 25.61713477207707
# differential_evolution step 973: f(x)= 25.61713477207707
# differential_evolution step 974: f(x)= 25.61713477207707
# differential_evolution step 975: f(x)= 25.61713477207707
# differential_evolution step 976: f(x)= 25.61713477207707
# differential_evolution step 977: f(x)= 25.61713477207707
# differential_evolution step 978: f(x)= 25.61713477207707
# differential_evolution step 979: f(x)= 25.61713477207707
# differential_evolution step 980: f(x)= 25.61713477207707
# differential_evolution step 981: f(x)= 25.435167438813096
# differential_evolution step 982: f(x)= 25.435167438813096
# differential_evolution step 983: f(x)= 25.435167438813096
# differential_evolution step 984: f(x)= 25.435167438813096
# differential_evolution step 985: f(x)= 25.435167438813096
# differential_evolution step 986: f(x)= 25.435167438813096
# differential_evolution step 987: f(x)= 25.435167438813096
# differential_evolution step 988: f(x)= 25.435167438813096
# differential_evolution step 989: f(x)= 25.435167438813096
# differential_evolution step 990: f(x)= 25.435167438813096
# differential_evolution step 991: f(x)= 25.435167438813096
# differential_evolution step 992: f(x)= 25.435167438813096
# differential_evolution step 993: f(x)= 25.435167438813096
# differential_evolution step 994: f(x)= 25.435167438813096
# differential_evolution step 995: f(x)= 25.435167438813096
# differential_evolution step 996: f(x)= 25.435167438813096
# differential_evolution step 997: f(x)= 25.435167438813096
# differential_evolution step 998: f(x)= 25.435167438813096
# differential_evolution step 999: f(x)= 25.435167438813096
# differential_evolution step 1000: f(x)= 25.435167438813096
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.9192, r_e=8.2462, n=2.3904, x_0=16.2450
# Sérsic 2: I_e=2.8773, r_e=4.1472, n=3.4505, x_0=41.0862
# Sérsic 3: I_e=0.7500, r_e=27.7329, n=1.9556, x_0=65.9643
# Sérsic 4: I_e=1.1886, r_e=10.2070, n=0.8136, x_0=61.2128
# Sérsic 5: I_e=0.5896, r_e=0.9610, n=1.7918, x_0=72.6510
# Sérsic 6: I_e=0.0845, r_e=4.4872, n=2.6562, x_0=91.8886
# Chi quadro minimo: 25.435167438813096
# False

# %%
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=0.9192, r_e=8.2462, n=2.3904, x_0=16.2450
# Sérsic 2: I_e=2.8773, r_e=4.1472, n=3.4505, x_0=41.0862
# Sérsic 3: I_e=0.7500, r_e=27.7329, n=1.9556, x_0=65.9643
# Sérsic 4: I_e=1.1886, r_e=10.2070, n=0.8136, x_0=61.2128
# Sérsic 5: I_e=0.5896, r_e=0.9610, n=1.7918, x_0=72.6510
# Sérsic 6: I_e=0.0845, r_e=4.4872, n=2.6562, x_0=91.8886
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = real_errors_OIII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.6394, r_e=9.9996, n=2.7272, x_0=16.1317
# Sérsic 2: I_e=3.8191, r_e=3.3492, n=3.2734, x_0=41.0881
# Sérsic 3: I_e=0.3522, r_e=49.8448, n=2.3759, x_0=65.9752
# Sérsic 4: I_e=3.3560, r_e=6.2010, n=0.2978, x_0=61.2105
# Sérsic 5: I_e=1.1936, r_e=1.8716, n=0.8053, x_0=72.7058
# Sérsic 6: I_e=0.0999, r_e=5.0000, n=2.3675, x_0=91.3611
# [5.71372783e-01 6.67304737e+00 7.08780711e-01 5.07732398e-02
#  2.50920309e+00 1.26497582e+00 7.11758940e-01 2.75959001e-02
#  5.87600508e-01 6.43190773e+01 1.25322571e+00 4.63182676e-02
#  4.44923193e-01 6.25788539e-01 7.32990037e-02 1.04856408e+00
#  1.70592940e+00 1.48512341e+00 1.14221641e+00 4.70936808e-01
#  8.33132647e-01 3.08350719e+01 6.57432098e+00 2.49680637e-01]
# 1.8055182545398607

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))
real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[2])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))
real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigmas[-1],
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[-1], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigmas[-1], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3) #, bounds = bounds_list, maxfev = 10000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit_continuum.csv", index= False)

# %% [markdown]
# ## Halpha and continuum

# %%
plt.figure(figsize=(8,6))
mask_continuum_3 = (wv > 6650)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
plt.plot(x_axes, radial_profile_HA, label ='Halpha') 
plt.plot(x_axes, radial_profile_continuum_3, label = 'Continuum')
plt.title(r'Halpha and Continuum')
plt.legend()
plt.grid()
plt.savefig('Halpha_continuum')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
