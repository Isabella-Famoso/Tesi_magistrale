# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_sx_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt")
z = red[1][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_sx_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4370.23874971 4371.69166732 4373.14458494 ... 6963.69669363 6965.14961125
#  6966.60252886] [0.03913203 0.03077905 0.03441105 ... 0.0256146  0.01966429 0.01886246] [0.0050932 0.0050932 0.0050932 ... 0.0050932 0.0050932 0.0050932]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18511937 2.18584583 2.18657229 ... 3.48184835 3.48257481 3.48330126]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3150, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314346256

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        91
# chi2/DOF: 0.01812; DOF: 1943; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:         9        47
# chi2/DOF: 0.01193; DOF: 1904; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 9.00626132, 46.62444316])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        39        52
#  comp.  1:         5        30
#  comp.  2:         2        25
# chi2/DOF: 0.5579; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.89      0.36       5    30
# Comp:  1                Halpha      34.63      0.36       5    30
# Comp:  2             [SII]6716      5.855      0.36       2    25
# Comp:  2             [SII]6731      3.797      0.36       2    25
# Comp:  2              HeII4687      0.000      0.36       2    25
# Comp:  2               HeI5876      1.687      0.36       2    25
# Comp:  2          [OIII]5007_d      10.48      0.45       2    25
# Comp:  2            [OI]6300_d     0.2015      0.45       2    25
# Comp:  2           [NII]6583_d      10.83      0.45       2    25
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  35.86; gas flux:     12 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    103; gas flux:     47 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  17.45; gas flux:      8 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  11.75; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  4.853; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  23.53; gas flux:     11 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.4696; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  24.84; gas flux:     15 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        43        41
#  comp.  1:         8        37
#  comp.  2:         1        17
# chi2/DOF: 0.5465; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.76      0.37       8    37
# Comp:  1                Halpha      36.21      0.37       8    37
# Comp:  2             [SII]6716      5.763      0.35       1    17
# Comp:  2             [SII]6731      3.748      0.35       1    17
# Comp:  2              HeII4687     0.3154      0.35       1    17
# Comp:  2               HeI5876      1.655      0.35       1    17
# Comp:  2          [OIII]5007_d      10.41      0.45       1    17
# Comp:  2            [OI]6300_d    0.02392      0.45       1    17
# Comp:  2           [NII]6583_d      10.65      0.45       1    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        64
#  comp.  1:         5        29
#  comp.  2:         1        14
# chi2/DOF: 0.5500; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.28      0.36       5    29
# Comp:  1                Halpha      34.25      0.36       5    29
# Comp:  2             [SII]6716      5.854      0.35       1    14
# Comp:  2             [SII]6731      3.556      0.35       1    14
# Comp:  2              HeII4687      0.000      0.35       1    14
# Comp:  2               HeI5876      1.820      0.35       1    14
# Comp:  2          [OIII]5007_d      9.943      0.44       1    14
# Comp:  2            [OI]6300_d     0.4724      0.44       1    14
# Comp:  2           [NII]6583_d      10.70      0.44       1    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       154
#  comp.  1:         5        27
#  comp.  2:         5        32
# chi2/DOF: 0.5432; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.43      0.36       5    27
# Comp:  1                Halpha      34.19      0.36       5    27
# Comp:  2             [SII]6716      5.587      0.37       5    32
# Comp:  2             [SII]6731      4.015      0.37       5    32
# Comp:  2              HeII4687     0.7620      0.37       5    32
# Comp:  2               HeI5876      1.710      0.37       5    32
# Comp:  2          [OIII]5007_d      10.08      0.46       5    32
# Comp:  2            [OI]6300_d     0.1098      0.46       5    32
# Comp:  2           [NII]6583_d      11.06      0.46       5    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        86       108
#  comp.  1:         7        30
#  comp.  2:        -0        25
# chi2/DOF: 0.5510; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.20      0.36       7    30
# Comp:  1                Halpha      34.48      0.36       7    30
# Comp:  2             [SII]6716      6.058      0.36      -0    25
# Comp:  2             [SII]6731      3.981      0.36      -0    25
# Comp:  2              HeII4687      0.000      0.36      -0    25
# Comp:  2               HeI5876      1.744      0.36      -0    25
# Comp:  2          [OIII]5007_d      9.841      0.45      -0    25
# Comp:  2            [OI]6300_d    0.04840      0.45      -0    25
# Comp:  2           [NII]6583_d      10.88      0.45      -0    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        95
#  comp.  1:         3        24
#  comp.  2:         2        21
# chi2/DOF: 0.5474; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.04      0.36       3    24
# Comp:  1                Halpha      33.54      0.36       3    24
# Comp:  2             [SII]6716      5.985      0.36       2    21
# Comp:  2             [SII]6731      3.731      0.36       2    21
# Comp:  2              HeII4687      0.000      0.36       2    21
# Comp:  2               HeI5876      1.513      0.36       2    21
# Comp:  2          [OIII]5007_d      10.87      0.45       2    21
# Comp:  2            [OI]6300_d     0.3246      0.45       2    21
# Comp:  2           [NII]6583_d      10.53      0.45       2    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        68
#  comp.  1:         6        26
#  comp.  2:         5        32
# chi2/DOF: 0.5460; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.39      0.36       6    26
# Comp:  1                Halpha      34.44      0.36       6    26
# Comp:  2             [SII]6716      5.855      0.37       5    32
# Comp:  2             [SII]6731      3.736      0.37       5    32
# Comp:  2              HeII4687      0.000      0.37       5    32
# Comp:  2               HeI5876      1.992      0.37       5    32
# Comp:  2          [OIII]5007_d      10.27      0.46       5    32
# Comp:  2            [OI]6300_d     0.1344      0.46       5    32
# Comp:  2           [NII]6583_d      10.93      0.46       5    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        47
#  comp.  1:         9        36
#  comp.  2:        -3        19
# chi2/DOF: 0.5397; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.37       9    36
# Comp:  1                Halpha      35.93      0.37       9    36
# Comp:  2             [SII]6716      5.725      0.35      -3    19
# Comp:  2             [SII]6731      3.960      0.35      -3    19
# Comp:  2              HeII4687      0.000      0.35      -3    19
# Comp:  2               HeI5876      1.617      0.35      -3    19
# Comp:  2          [OIII]5007_d      10.33      0.45      -3    19
# Comp:  2            [OI]6300_d     0.2104      0.45      -3    19
# Comp:  2           [NII]6583_d      10.77      0.45      -3    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42        57
#  comp.  1:         2        22
#  comp.  2:         4        33
# chi2/DOF: 0.5413; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.64      0.36       2    22
# Comp:  1                Halpha      33.32      0.36       2    22
# Comp:  2             [SII]6716      6.156      0.37       4    33
# Comp:  2             [SII]6731      4.079      0.37       4    33
# Comp:  2              HeII4687     0.8145      0.37       4    33
# Comp:  2               HeI5876      1.990      0.37       4    33
# Comp:  2          [OIII]5007_d      10.18      0.46       4    33
# Comp:  2            [OI]6300_d     0.3735      0.46       4    33
# Comp:  2           [NII]6583_d      11.19      0.46       4    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        14
#  comp.  1:         7        27
#  comp.  2:         2        27
# chi2/DOF: 0.5517; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.09      0.36       7    27
# Comp:  1                Halpha      34.35      0.36       7    27
# Comp:  2             [SII]6716      6.207      0.36       2    27
# Comp:  2             [SII]6731      3.747      0.36       2    27
# Comp:  2              HeII4687     0.6964      0.36       2    27
# Comp:  2               HeI5876      1.796      0.36       2    27
# Comp:  2          [OIII]5007_d      10.81      0.46       2    27
# Comp:  2            [OI]6300_d     0.2557      0.46       2    27
# Comp:  2           [NII]6583_d      11.09      0.46       2    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        68
#  comp.  1:         8        36
#  comp.  2:         1        19
# chi2/DOF: 0.5422; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.12      0.37       8    36
# Comp:  1                Halpha      36.01      0.37       8    36
# Comp:  2             [SII]6716      5.831      0.35       1    19
# Comp:  2             [SII]6731      3.943      0.35       1    19
# Comp:  2              HeII4687      0.000      0.35       1    19
# Comp:  2               HeI5876      1.951      0.35       1    19
# Comp:  2          [OIII]5007_d      10.03      0.45       1    19
# Comp:  2            [OI]6300_d     0.3730      0.45       1    19
# Comp:  2           [NII]6583_d      10.75      0.45       1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        54
#  comp.  1:         2        21
#  comp.  2:         1        16
# chi2/DOF: 0.5383; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.97      0.36       2    21
# Comp:  1                Halpha      34.00      0.36       2    21
# Comp:  2             [SII]6716      5.891      0.35       1    16
# Comp:  2             [SII]6731      3.705      0.35       1    16
# Comp:  2              HeII4687     0.6266      0.35       1    16
# Comp:  2               HeI5876      1.658      0.35       1    16
# Comp:  2          [OIII]5007_d      9.847      0.45       1    16
# Comp:  2            [OI]6300_d     0.3529      0.45       1    16
# Comp:  2           [NII]6583_d      10.57      0.45       1    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        35
#  comp.  1:         7        39
#  comp.  2:         2        25
# chi2/DOF: 0.5395; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.55      0.37       7    39
# Comp:  1                Halpha      36.46      0.37       7    39
# Comp:  2             [SII]6716      5.775      0.36       2    25
# Comp:  2             [SII]6731      3.783      0.36       2    25
# Comp:  2              HeII4687      0.000      0.36       2    25
# Comp:  2               HeI5876      2.069      0.36       2    25
# Comp:  2          [OIII]5007_d      9.555      0.45       2    25
# Comp:  2            [OI]6300_d    0.06974      0.45       2    25
# Comp:  2           [NII]6583_d      10.66      0.45       2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        65
#  comp.  1:         6        29
#  comp.  2:        -2        26
# chi2/DOF: 0.5510; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.36       6    29
# Comp:  1                Halpha      34.94      0.36       6    29
# Comp:  2             [SII]6716      6.030      0.36      -2    26
# Comp:  2             [SII]6731      3.843      0.36      -2    26
# Comp:  2              HeII4687     0.3266      0.36      -2    26
# Comp:  2               HeI5876      1.832      0.36      -2    26
# Comp:  2          [OIII]5007_d      10.49      0.45      -2    26
# Comp:  2            [OI]6300_d     0.1276      0.45      -2    26
# Comp:  2           [NII]6583_d      10.63      0.45      -2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59        42
#  comp.  1:         9        37
#  comp.  2:         1        30
# chi2/DOF: 0.5457; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.99      0.37       9    37
# Comp:  1                Halpha      36.20      0.37       9    37
# Comp:  2             [SII]6716      6.145      0.36       1    30
# Comp:  2             [SII]6731      3.807      0.36       1    30
# Comp:  2              HeII4687      0.000      0.36       1    30
# Comp:  2               HeI5876      1.919      0.36       1    30
# Comp:  2          [OIII]5007_d      11.06      0.46       1    30
# Comp:  2            [OI]6300_d     0.1628      0.46       1    30
# Comp:  2           [NII]6583_d      11.08      0.46       1    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        67
#  comp.  1:         3        18
#  comp.  2:         2        13
# chi2/DOF: 0.5454; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.09      0.35       3    18
# Comp:  1                Halpha      32.84      0.35       3    18
# Comp:  2             [SII]6716      5.812      0.35       2    13
# Comp:  2             [SII]6731      3.476      0.35       2    13
# Comp:  2              HeII4687      0.000      0.35       2    13
# Comp:  2               HeI5876      1.652      0.35       2    13
# Comp:  2          [OIII]5007_d      10.52      0.44       2    13
# Comp:  2            [OI]6300_d     0.2111      0.44       2    13
# Comp:  2           [NII]6583_d      10.39      0.44       2    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        72
#  comp.  1:         6        26
#  comp.  2:         4        28
# chi2/DOF: 0.5471; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.07      0.36       6    26
# Comp:  1                Halpha      34.75      0.36       6    26
# Comp:  2             [SII]6716      5.717      0.36       4    28
# Comp:  2             [SII]6731      3.669      0.36       4    28
# Comp:  2              HeII4687     0.7485      0.36       4    28
# Comp:  2               HeI5876      1.905      0.36       4    28
# Comp:  2          [OIII]5007_d      11.20      0.46       4    28
# Comp:  2            [OI]6300_d    0.06784      0.46       4    28
# Comp:  2           [NII]6583_d      11.07      0.46       4    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        71        43
#  comp.  1:         3        26
#  comp.  2:         2        15
# chi2/DOF: 0.5439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.11      0.36       3    26
# Comp:  1                Halpha      33.47      0.36       3    26
# Comp:  2             [SII]6716      6.036      0.35       2    15
# Comp:  2             [SII]6731      3.805      0.35       2    15
# Comp:  2              HeII4687     0.1604      0.35       2    15
# Comp:  2               HeI5876      1.834      0.35       2    15
# Comp:  2          [OIII]5007_d      9.892      0.44       2    15
# Comp:  2            [OI]6300_d    0.04432      0.44       2    15
# Comp:  2           [NII]6583_d      10.39      0.44       2    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        57
#  comp.  1:         7        34
#  comp.  2:         3        25
# chi2/DOF: 0.5517; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.05      0.37       7    34
# Comp:  1                Halpha      34.57      0.37       7    34
# Comp:  2             [SII]6716      5.922      0.36       3    25
# Comp:  2             [SII]6731      3.577      0.36       3    25
# Comp:  2              HeII4687      0.000      0.36       3    25
# Comp:  2               HeI5876      1.887      0.36       3    25
# Comp:  2          [OIII]5007_d      11.23      0.45       3    25
# Comp:  2            [OI]6300_d      0.000      0.45       3    25
# Comp:  2           [NII]6583_d      10.84      0.45       3    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        12
#  comp.  1:         4        23
#  comp.  2:         3        12
# chi2/DOF: 0.5467; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.11      0.36       4    23
# Comp:  1                Halpha      33.69      0.36       4    23
# Comp:  2             [SII]6716      6.023      0.35       3    12
# Comp:  2             [SII]6731      3.658      0.35       3    12
# Comp:  2              HeII4687      0.000      0.35       3    12
# Comp:  2               HeI5876      1.707      0.35       3    12
# Comp:  2          [OIII]5007_d      10.42      0.44       3    12
# Comp:  2            [OI]6300_d     0.4597      0.44       3    12
# Comp:  2           [NII]6583_d      10.65      0.44       3    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:         4        24
#  comp.  2:         0        34
# chi2/DOF: 0.5479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.93      0.36       4    24
# Comp:  1                Halpha      33.84      0.36       4    24
# Comp:  2             [SII]6716      5.677      0.37       0    34
# Comp:  2             [SII]6731      4.081      0.37       0    34
# Comp:  2              HeII4687      0.000      0.37       0    34
# Comp:  2               HeI5876      1.565      0.37       0    34
# Comp:  2          [OIII]5007_d      10.59      0.46       0    34
# Comp:  2            [OI]6300_d     0.2504      0.46       0    34
# Comp:  2           [NII]6583_d      11.29      0.46       0    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
#  comp.  1:         6        28
#  comp.  2:         1        21
# chi2/DOF: 0.5493; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.72      0.36       6    28
# Comp:  1                Halpha      34.75      0.36       6    28
# Comp:  2             [SII]6716      5.879      0.36       1    21
# Comp:  2             [SII]6731      3.822      0.36       1    21
# Comp:  2              HeII4687     0.6232      0.36       1    21
# Comp:  2               HeI5876      1.790      0.36       1    21
# Comp:  2          [OIII]5007_d      10.72      0.45       1    21
# Comp:  2            [OI]6300_d     0.4527      0.45       1    21
# Comp:  2           [NII]6583_d      10.87      0.45       1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58        53
#  comp.  1:         4        27
#  comp.  2:        -1        24
# chi2/DOF: 0.5473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.06      0.36       4    27
# Comp:  1                Halpha      33.30      0.36       4    27
# Comp:  2             [SII]6716      5.943      0.36      -1    24
# Comp:  2             [SII]6731      3.938      0.36      -1    24
# Comp:  2              HeII4687      0.000      0.36      -1    24
# Comp:  2               HeI5876      1.761      0.36      -1    24
# Comp:  2          [OIII]5007_d      10.57      0.45      -1    24
# Comp:  2            [OI]6300_d     0.2353      0.45      -1    24
# Comp:  2           [NII]6583_d      10.78      0.45      -1    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        59
#  comp.  1:         8        36
#  comp.  2:         4        30
# chi2/DOF: 0.5458; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.11      0.37       8    36
# Comp:  1                Halpha      36.18      0.37       8    36
# Comp:  2             [SII]6716      6.025      0.36       4    30
# Comp:  2             [SII]6731      4.007      0.36       4    30
# Comp:  2              HeII4687      0.000      0.36       4    30
# Comp:  2               HeI5876      1.547      0.36       4    30
# Comp:  2          [OIII]5007_d      10.81      0.46       4    30
# Comp:  2            [OI]6300_d     0.3309      0.46       4    30
# Comp:  2           [NII]6583_d      11.01      0.46       4    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13        32
#  comp.  1:         6        30
#  comp.  2:        -0        24
# chi2/DOF: 0.5465; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.51      0.36       6    30
# Comp:  1                Halpha      35.27      0.36       6    30
# Comp:  2             [SII]6716      6.173      0.36      -0    24
# Comp:  2             [SII]6731      3.908      0.36      -0    24
# Comp:  2              HeII4687     0.5719      0.36      -0    24
# Comp:  2               HeI5876      1.680      0.36      -0    24
# Comp:  2          [OIII]5007_d      11.13      0.45      -0    24
# Comp:  2            [OI]6300_d     0.1910      0.45      -0    24
# Comp:  2           [NII]6583_d      11.06      0.45      -0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        80
#  comp.  1:         9        37
#  comp.  2:         4        35
# chi2/DOF: 0.5427; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.73      0.37       9    37
# Comp:  1                Halpha      35.55      0.37       9    37
# Comp:  2             [SII]6716      6.448      0.37       4    35
# Comp:  2             [SII]6731      3.857      0.37       4    35
# Comp:  2              HeII4687     0.4376      0.37       4    35
# Comp:  2               HeI5876      1.784      0.37       4    35
# Comp:  2          [OIII]5007_d      11.32      0.47       4    35
# Comp:  2            [OI]6300_d    0.04553      0.47       4    35
# Comp:  2           [NII]6583_d      10.98      0.47       4    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        22
#  comp.  1:         3        17
#  comp.  2:         1        29
# chi2/DOF: 0.5369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.58      0.35       3    17
# Comp:  1                Halpha      33.44      0.35       3    17
# Comp:  2             [SII]6716      5.595      0.36       1    29
# Comp:  2             [SII]6731      3.960      0.36       1    29
# Comp:  2              HeII4687     0.4455      0.36       1    29
# Comp:  2               HeI5876      1.742      0.36       1    29
# Comp:  2          [OIII]5007_d      11.61      0.46       1    29
# Comp:  2            [OI]6300_d    0.08629      0.46       1    29
# Comp:  2           [NII]6583_d      11.12      0.46       1    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49        49
#  comp.  1:         2        26
#  comp.  2:        -1        28
# chi2/DOF: 0.5447; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.97      0.36       2    26
# Comp:  1                Halpha      33.93      0.36       2    26
# Comp:  2             [SII]6716      5.953      0.36      -1    28
# Comp:  2             [SII]6731      3.662      0.36      -1    28
# Comp:  2              HeII4687     0.6311      0.36      -1    28
# Comp:  2               HeI5876      1.806      0.36      -1    28
# Comp:  2          [OIII]5007_d      10.77      0.46      -1    28
# Comp:  2            [OI]6300_d     0.1541      0.46      -1    28
# Comp:  2           [NII]6583_d      11.00      0.46      -1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        33
#  comp.  1:         6        29
#  comp.  2:         2        23
# chi2/DOF: 0.5518; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.86      0.36       6    29
# Comp:  1                Halpha      35.19      0.36       6    29
# Comp:  2             [SII]6716      5.978      0.36       2    23
# Comp:  2             [SII]6731      3.824      0.36       2    23
# Comp:  2              HeII4687      0.000      0.36       2    23
# Comp:  2               HeI5876      1.603      0.36       2    23
# Comp:  2          [OIII]5007_d      10.14      0.45       2    23
# Comp:  2            [OI]6300_d     0.4084      0.45       2    23
# Comp:  2           [NII]6583_d      10.72      0.45       2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        24
#  comp.  1:         6        29
#  comp.  2:         4        30
# chi2/DOF: 0.5510; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.17      0.36       6    29
# Comp:  1                Halpha      35.21      0.36       6    29
# Comp:  2             [SII]6716      5.917      0.36       4    30
# Comp:  2             [SII]6731      3.876      0.36       4    30
# Comp:  2              HeII4687      0.000      0.36       4    30
# Comp:  2               HeI5876      1.848      0.36       4    30
# Comp:  2          [OIII]5007_d      10.34      0.46       4    30
# Comp:  2            [OI]6300_d     0.2896      0.46       4    30
# Comp:  2           [NII]6583_d      10.77      0.46       4    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22         1
#  comp.  1:         4        19
#  comp.  2:        -1        21
# chi2/DOF: 0.5414; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.29      0.35       4    19
# Comp:  1                Halpha      33.02      0.35       4    19
# Comp:  2             [SII]6716      5.714      0.36      -1    21
# Comp:  2             [SII]6731      3.982      0.36      -1    21
# Comp:  2              HeII4687     0.2697      0.36      -1    21
# Comp:  2               HeI5876      1.914      0.36      -1    21
# Comp:  2          [OIII]5007_d      11.02      0.45      -1    21
# Comp:  2            [OI]6300_d     0.2729      0.45      -1    21
# Comp:  2           [NII]6583_d      10.58      0.45      -1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52         7
#  comp.  1:         8        37
#  comp.  2:         1        31
# chi2/DOF: 0.5489; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.50      0.37       8    37
# Comp:  1                Halpha      35.95      0.37       8    37
# Comp:  2             [SII]6716      5.868      0.37       1    31
# Comp:  2             [SII]6731      4.009      0.37       1    31
# Comp:  2              HeII4687      0.000      0.37       1    31
# Comp:  2               HeI5876      1.629      0.37       1    31
# Comp:  2          [OIII]5007_d      10.75      0.46       1    31
# Comp:  2            [OI]6300_d    0.04890      0.46       1    31
# Comp:  2           [NII]6583_d      11.18      0.46       1    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        90
#  comp.  1:         6        27
#  comp.  2:         4        27
# chi2/DOF: 0.5463; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.33      0.36       6    27
# Comp:  1                Halpha      34.26      0.36       6    27
# Comp:  2             [SII]6716      5.984      0.36       4    27
# Comp:  2             [SII]6731      3.937      0.36       4    27
# Comp:  2              HeII4687      0.000      0.36       4    27
# Comp:  2               HeI5876      1.593      0.36       4    27
# Comp:  2          [OIII]5007_d      11.50      0.46       4    27
# Comp:  2            [OI]6300_d    0.09213      0.46       4    27
# Comp:  2           [NII]6583_d      10.92      0.46       4    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        26
#  comp.  1:         7        24
#  comp.  2:         4        29
# chi2/DOF: 0.5463; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.30      0.36       7    24
# Comp:  1                Halpha      34.15      0.36       7    24
# Comp:  2             [SII]6716      6.130      0.36       4    29
# Comp:  2             [SII]6731      3.615      0.36       4    29
# Comp:  2              HeII4687      0.000      0.36       4    29
# Comp:  2               HeI5876      1.556      0.36       4    29
# Comp:  2          [OIII]5007_d      11.48      0.46       4    29
# Comp:  2            [OI]6300_d     0.2119      0.46       4    29
# Comp:  2           [NII]6583_d      10.75      0.46       4    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18       249
#  comp.  1:         3        21
#  comp.  2:         6        28
# chi2/DOF: 0.5404; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.97      0.36       3    21
# Comp:  1                Halpha      33.00      0.36       3    21
# Comp:  2             [SII]6716      6.299      0.36       6    28
# Comp:  2             [SII]6731      3.828      0.36       6    28
# Comp:  2              HeII4687      0.000      0.36       6    28
# Comp:  2               HeI5876      2.007      0.36       6    28
# Comp:  2          [OIII]5007_d      10.47      0.46       6    28
# Comp:  2            [OI]6300_d     0.1244      0.46       6    28
# Comp:  2           [NII]6583_d      10.99      0.46       6    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52         5
#  comp.  1:         4        23
#  comp.  2:         2        18
# chi2/DOF: 0.5480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.74      0.36       4    23
# Comp:  1                Halpha      33.08      0.36       4    23
# Comp:  2             [SII]6716      5.624      0.35       2    18
# Comp:  2             [SII]6731      3.672      0.35       2    18
# Comp:  2              HeII4687     0.2925      0.35       2    18
# Comp:  2               HeI5876      1.842      0.35       2    18
# Comp:  2          [OIII]5007_d      10.14      0.45       2    18
# Comp:  2            [OI]6300_d     0.1026      0.45       2    18
# Comp:  2           [NII]6583_d      10.42      0.45       2    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        48
#  comp.  1:         5        36
#  comp.  2:         2        24
# chi2/DOF: 0.5465; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.77      0.37       5    36
# Comp:  1                Halpha      35.07      0.37       5    36
# Comp:  2             [SII]6716      6.228      0.36       2    24
# Comp:  2             [SII]6731      4.029      0.36       2    24
# Comp:  2              HeII4687     0.6026      0.36       2    24
# Comp:  2               HeI5876      1.837      0.36       2    24
# Comp:  2          [OIII]5007_d      10.89      0.45       2    24
# Comp:  2            [OI]6300_d     0.3286      0.45       2    24
# Comp:  2           [NII]6583_d      10.75      0.45       2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63         1
#  comp.  1:         4        32
#  comp.  2:         5        19
# chi2/DOF: 0.5477; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.94      0.37       4    32
# Comp:  1                Halpha      34.94      0.37       4    32
# Comp:  2             [SII]6716      5.410      0.35       5    19
# Comp:  2             [SII]6731      3.503      0.35       5    19
# Comp:  2              HeII4687     0.5742      0.35       5    19
# Comp:  2               HeI5876      1.352      0.35       5    19
# Comp:  2          [OIII]5007_d      10.97      0.45       5    19
# Comp:  2            [OI]6300_d     0.2813      0.45       5    19
# Comp:  2           [NII]6583_d      10.59      0.45       5    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68        50
#  comp.  1:         4        18
#  comp.  2:         3        28
# chi2/DOF: 0.5404; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.74      0.35       4    18
# Comp:  1                Halpha      32.94      0.35       4    18
# Comp:  2             [SII]6716      5.937      0.36       3    28
# Comp:  2             [SII]6731      3.649      0.36       3    28
# Comp:  2              HeII4687     0.3829      0.36       3    28
# Comp:  2               HeI5876      1.449      0.36       3    28
# Comp:  2          [OIII]5007_d      11.07      0.46       3    28
# Comp:  2            [OI]6300_d     0.1596      0.46       3    28
# Comp:  2           [NII]6583_d      10.71      0.46       3    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        53
#  comp.  1:         4        20
#  comp.  2:         5        22
# chi2/DOF: 0.5468; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.98      0.36       4    20
# Comp:  1                Halpha      33.49      0.36       4    20
# Comp:  2             [SII]6716      5.858      0.36       5    22
# Comp:  2             [SII]6731      3.589      0.36       5    22
# Comp:  2              HeII4687      0.000      0.36       5    22
# Comp:  2               HeI5876      1.705      0.36       5    22
# Comp:  2          [OIII]5007_d      10.48      0.45       5    22
# Comp:  2            [OI]6300_d    0.04454      0.45       5    22
# Comp:  2           [NII]6583_d      10.90      0.45       5    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45         1
#  comp.  1:         6        33
#  comp.  2:         3        32
# chi2/DOF: 0.5516; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.08      0.37       6    33
# Comp:  1                Halpha      34.69      0.37       6    33
# Comp:  2             [SII]6716      5.854      0.37       3    32
# Comp:  2             [SII]6731      3.844      0.37       3    32
# Comp:  2              HeII4687      0.000      0.37       3    32
# Comp:  2               HeI5876      1.689      0.37       3    32
# Comp:  2          [OIII]5007_d      11.29      0.46       3    32
# Comp:  2            [OI]6300_d      0.000      0.46       3    32
# Comp:  2           [NII]6583_d      11.27      0.46       3    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23        81
#  comp.  1:         8        39
#  comp.  2:         5        25
# chi2/DOF: 0.5379; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.18      0.37       8    39
# Comp:  1                Halpha      36.54      0.37       8    39
# Comp:  2             [SII]6716      6.041      0.36       5    25
# Comp:  2             [SII]6731      3.651      0.36       5    25
# Comp:  2              HeII4687     0.5559      0.36       5    25
# Comp:  2               HeI5876      1.917      0.36       5    25
# Comp:  2          [OIII]5007_d      9.883      0.45       5    25
# Comp:  2            [OI]6300_d    0.02888      0.45       5    25
# Comp:  2           [NII]6583_d      10.87      0.45       5    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        97        79
#  comp.  1:         5        32
#  comp.  2:         3        30
# chi2/DOF: 0.5487; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.69      0.37       5    32
# Comp:  1                Halpha      35.14      0.37       5    32
# Comp:  2             [SII]6716      5.556      0.36       3    30
# Comp:  2             [SII]6731      3.895      0.36       3    30
# ...
# chi2/DOF: 0.5449; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.63      0.37       8    33
# Comp:  1                Halpha      35.23      0.37       8    33
# Comp:  2             [SII]6716      5.704      0.35       2     1
# Comp:  2             [SII]6731      3.460      0.35       2     1
# Comp:  2              HeII4687     0.7473      0.35       2     1
# Comp:  2               HeI5876      1.588      0.35       2     1
# Comp:  2          [OIII]5007_d      10.33      0.44       2     1
# Comp:  2            [OI]6300_d     0.3132      0.44       2     1
# Comp:  2           [NII]6583_d      10.32      0.44       2     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61        85
#  comp.  1:         5        29
#  comp.  2:         5        31
# chi2/DOF: 0.5465; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.02      0.36       5    29
# Comp:  1                Halpha      35.22      0.36       5    29
# Comp:  2             [SII]6716      5.762      0.37       5    31
# Comp:  2             [SII]6731      3.650      0.37       5    31
# Comp:  2              HeII4687      0.000      0.37       5    31
# Comp:  2               HeI5876      1.953      0.37       5    31
# Comp:  2          [OIII]5007_d      11.23      0.46       5    31
# Comp:  2            [OI]6300_d     0.1101      0.46       5    31
# Comp:  2           [NII]6583_d      11.10      0.46       5    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        21
#  comp.  1:         6        32
#  comp.  2:         1        19
# chi2/DOF: 0.5486; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.47      0.37       6    32
# Comp:  1                Halpha      34.36      0.37       6    32
# Comp:  2             [SII]6716      5.857      0.35       1    19
# Comp:  2             [SII]6731      3.764      0.35       1    19
# Comp:  2              HeII4687      0.000      0.35       1    19
# Comp:  2               HeI5876      1.776      0.35       1    19
# Comp:  2          [OIII]5007_d      9.483      0.45       1    19
# Comp:  2            [OI]6300_d     0.4620      0.45       1    19
# Comp:  2           [NII]6583_d      10.67      0.45       1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68        90
#  comp.  1:         7        26
#  comp.  2:        -2        23
# chi2/DOF: 0.5495; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.19      0.36       7    26
# Comp:  1                Halpha      34.22      0.36       7    26
# Comp:  2             [SII]6716      5.691      0.36      -2    23
# Comp:  2             [SII]6731      3.896      0.36      -2    23
# Comp:  2              HeII4687     0.5333      0.36      -2    23
# Comp:  2               HeI5876      1.888      0.36      -2    23
# Comp:  2          [OIII]5007_d      9.847      0.45      -2    23
# Comp:  2            [OI]6300_d     0.3081      0.45      -2    23
# Comp:  2           [NII]6583_d      10.78      0.45      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        66         1
#  comp.  1:        10        34
#  comp.  2:        -0        24
# chi2/DOF: 0.5446; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.62      0.37      10    34
# Comp:  1                Halpha      35.50      0.37      10    34
# Comp:  2             [SII]6716      5.439      0.36      -0    24
# Comp:  2             [SII]6731      3.876      0.36      -0    24
# Comp:  2              HeII4687      0.000      0.36      -0    24
# Comp:  2               HeI5876      1.852      0.36      -0    24
# Comp:  2          [OIII]5007_d      10.62      0.45      -0    24
# Comp:  2            [OI]6300_d     0.3896      0.45      -0    24
# Comp:  2           [NII]6583_d      10.92      0.45      -0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1         1
#  comp.  1:         3        24
#  comp.  2:        -1        11
# chi2/DOF: 0.5464; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.19      0.36       3    24
# Comp:  1                Halpha      33.42      0.36       3    24
# Comp:  2             [SII]6716      5.812      0.35      -1    11
# Comp:  2             [SII]6731      3.703      0.35      -1    11
# Comp:  2              HeII4687     0.1657      0.35      -1    11
# Comp:  2               HeI5876      1.656      0.35      -1    11
# Comp:  2          [OIII]5007_d      9.715      0.44      -1    11
# Comp:  2            [OI]6300_d     0.1466      0.44      -1    11
# Comp:  2           [NII]6583_d      10.43      0.44      -1    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        64        49
#  comp.  1:         7        37
#  comp.  2:         4        25
# chi2/DOF: 0.5478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.23      0.37       7    37
# Comp:  1                Halpha      35.95      0.37       7    37
# Comp:  2             [SII]6716      5.864      0.36       4    25
# Comp:  2             [SII]6731      4.057      0.36       4    25
# Comp:  2              HeII4687      0.000      0.36       4    25
# Comp:  2               HeI5876      1.697      0.36       4    25
# Comp:  2          [OIII]5007_d      11.07      0.45       4    25
# Comp:  2            [OI]6300_d      0.000      0.45       4    25
# Comp:  2           [NII]6583_d      10.82      0.45       4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6        62
#  comp.  1:         8        37
#  comp.  2:         2        23
# chi2/DOF: 0.5432; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.48      0.37       8    37
# Comp:  1                Halpha      36.06      0.37       8    37
# Comp:  2             [SII]6716      6.171      0.36       2    23
# Comp:  2             [SII]6731      4.008      0.36       2    23
# Comp:  2              HeII4687     0.4656      0.36       2    23
# Comp:  2               HeI5876      1.369      0.36       2    23
# Comp:  2          [OIII]5007_d      10.95      0.45       2    23
# Comp:  2            [OI]6300_d     0.4655      0.45       2    23
# Comp:  2           [NII]6583_d      10.77      0.45       2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        14
#  comp.  1:         7        35
#  comp.  2:         1        35
# chi2/DOF: 0.5433; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.14      0.37       7    35
# Comp:  1                Halpha      36.39      0.37       7    35
# Comp:  2             [SII]6716      5.988      0.37       1    35
# Comp:  2             [SII]6731      4.182      0.37       1    35
# Comp:  2              HeII4687      0.000      0.37       1    35
# Comp:  2               HeI5876      1.753      0.37       1    35
# Comp:  2          [OIII]5007_d      11.07      0.47       1    35
# Comp:  2            [OI]6300_d     0.4024      0.47       1    35
# Comp:  2           [NII]6583_d      11.31      0.47       1    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        59
#  comp.  1:         6        32
#  comp.  2:         3        36
# chi2/DOF: 0.5541; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.47      0.37       6    32
# Comp:  1                Halpha      34.87      0.37       6    32
# Comp:  2             [SII]6716      6.304      0.37       3    36
# Comp:  2             [SII]6731      4.168      0.37       3    36
# Comp:  2              HeII4687      0.000      0.37       3    36
# Comp:  2               HeI5876      1.828      0.37       3    36
# Comp:  2          [OIII]5007_d      10.51      0.47       3    36
# Comp:  2            [OI]6300_d     0.2533      0.47       3    36
# Comp:  2           [NII]6583_d      11.12      0.47       3    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39         1
#  comp.  1:         4        35
#  comp.  2:         3        24
# chi2/DOF: 0.5475; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.93      0.37       4    35
# Comp:  1                Halpha      35.18      0.37       4    35
# Comp:  2             [SII]6716      5.914      0.36       3    24
# Comp:  2             [SII]6731      4.066      0.36       3    24
# Comp:  2              HeII4687     0.1457      0.36       3    24
# Comp:  2               HeI5876      1.507      0.36       3    24
# Comp:  2          [OIII]5007_d      11.37      0.45       3    24
# Comp:  2            [OI]6300_d     0.2401      0.45       3    24
# Comp:  2           [NII]6583_d      10.79      0.45       3    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        40
#  comp.  1:         8        36
#  comp.  2:         3        20
# chi2/DOF: 0.5467; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.41      0.37       8    36
# Comp:  1                Halpha      36.14      0.37       8    36
# Comp:  2             [SII]6716      5.881      0.36       3    20
# Comp:  2             [SII]6731      3.910      0.36       3    20
# Comp:  2              HeII4687      0.000      0.36       3    20
# Comp:  2               HeI5876      1.690      0.36       3    20
# Comp:  2          [OIII]5007_d      10.86      0.45       3    20
# Comp:  2            [OI]6300_d      0.000      0.45       3    20
# Comp:  2           [NII]6583_d      10.52      0.45       3    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52         1
#  comp.  1:         5        34
#  comp.  2:         4        24
# chi2/DOF: 0.5482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.11      0.37       5    34
# Comp:  1                Halpha      34.74      0.37       5    34
# Comp:  2             [SII]6716      6.011      0.36       4    24
# Comp:  2             [SII]6731      3.806      0.36       4    24
# Comp:  2              HeII4687     0.2830      0.36       4    24
# Comp:  2               HeI5876      1.661      0.36       4    24
# Comp:  2          [OIII]5007_d      10.39      0.45       4    24
# Comp:  2            [OI]6300_d     0.1048      0.45       4    24
# Comp:  2           [NII]6583_d      10.86      0.45       4    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        70
#  comp.  1:         6        29
#  comp.  2:         2        36
# chi2/DOF: 0.5514; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.73      0.36       6    29
# Comp:  1                Halpha      34.55      0.36       6    29
# Comp:  2             [SII]6716      6.119      0.37       2    36
# Comp:  2             [SII]6731      3.936      0.37       2    36
# Comp:  2              HeII4687     0.3205      0.37       2    36
# Comp:  2               HeI5876      1.841      0.37       2    36
# Comp:  2          [OIII]5007_d      10.60      0.47       2    36
# Comp:  2            [OI]6300_d     0.3353      0.47       2    36
# Comp:  2           [NII]6583_d      11.04      0.47       2    36
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_sx_2_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_sx_2", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_sx_2_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_sx_2_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_sx_2_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
