# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_10.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = red[0][9]
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_10']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4270.21582734 4271.63549161 4273.05515588 ... 6804.31654676 6805.73621103
#  6807.1558753 ] [0.26804485 0.22196613 0.19393444 ... 0.3777654  0.39279089 0.39637192] [0.0218925 0.0218925 0.0218925 ... 0.0218925 0.0218925 0.0218925]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.13510791 2.13581775 2.13652758 ... 3.40215827 3.40286811 3.40357794]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3173, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314399511

# %%
stars_templates.shape
# Out:
# (3173, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3173, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        20        71
# chi2/DOF: 0.002073; DOF: 1911; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:        12        81
# chi2/DOF: 0.001528; DOF: 1892; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([11.59920343, 80.66074631])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        81
#  comp.  1:       -17        49
#  comp.  2:       -23        49
# chi2/DOF: 0.6183; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.129      0.14     -17    49
# Comp:  1                 Hbeta      5.593      0.14     -17    49
# Comp:  1                Halpha      26.13      0.14     -17    49
# Comp:  2             [SII]6716      4.671      0.14     -23    49
# Comp:  2             [SII]6731      3.222      0.14     -23    49
# Comp:  2              HeII4687      0.000      0.14     -23    49
# Comp:  2               HeI5876     0.5163      0.14     -23    49
# Comp:  2          [OIII]5007_d      1.922      0.18     -23    49
# Comp:  2            [OI]6300_d     0.8427      0.18     -23    49
# Comp:  2           [NII]6583_d      12.17      0.18     -23    49
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  15.31; gas flux:      2 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  39.39; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  180.8; gas flux:     36 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  33.56; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  22.21; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   3.79; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  10.59; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.467; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  64.28; gas flux:     17 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        86
#  comp.  1:       -17        53
#  comp.  2:       -22        49
# chi2/DOF: 0.5968; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.022      0.14     -17    53
# Comp:  1                 Hbeta      5.492      0.14     -17    53
# Comp:  1                Halpha      26.69      0.14     -17    53
# Comp:  2             [SII]6716      4.746      0.14     -22    49
# Comp:  2             [SII]6731      3.189      0.14     -22    49
# Comp:  2              HeII4687      0.000      0.14     -22    49
# Comp:  2               HeI5876     0.4995      0.14     -22    49
# Comp:  2          [OIII]5007_d      2.008      0.18     -22    49
# Comp:  2            [OI]6300_d     0.8430      0.18     -22    49
# Comp:  2           [NII]6583_d      12.30      0.18     -22    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        60
#  comp.  1:       -14        51
#  comp.  2:       -22        55
# chi2/DOF: 0.5974; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.942      0.14     -14    51
# Comp:  1                 Hbeta      5.843      0.14     -14    51
# Comp:  1                Halpha      26.22      0.14     -14    51
# Comp:  2             [SII]6716      4.811      0.14     -22    55
# Comp:  2             [SII]6731      3.333      0.14     -22    55
# Comp:  2              HeII4687      0.000      0.14     -22    55
# Comp:  2               HeI5876     0.6971      0.14     -22    55
# Comp:  2          [OIII]5007_d      1.881      0.18     -22    55
# Comp:  2            [OI]6300_d     0.8665      0.18     -22    55
# Comp:  2           [NII]6583_d      12.53      0.18     -22    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        77
#  comp.  1:       -16        52
#  comp.  2:       -21        53
# chi2/DOF: 0.5888; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.042      0.14     -16    52
# Comp:  1                 Hbeta      6.407      0.14     -16    52
# Comp:  1                Halpha      26.66      0.14     -16    52
# Comp:  2             [SII]6716      4.758      0.14     -21    53
# Comp:  2             [SII]6731      3.281      0.14     -21    53
# Comp:  2              HeII4687    0.03161      0.14     -21    53
# Comp:  2               HeI5876     0.6051      0.14     -21    53
# Comp:  2          [OIII]5007_d      1.761      0.18     -21    53
# Comp:  2            [OI]6300_d     0.8349      0.18     -21    53
# Comp:  2           [NII]6583_d      12.46      0.18     -21    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        84
#  comp.  1:       -17        46
#  comp.  2:       -25        45
# chi2/DOF: 0.6052; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.923      0.14     -17    46
# Comp:  1                 Hbeta      5.365      0.14     -17    46
# Comp:  1                Halpha      25.66      0.14     -17    46
# Comp:  2             [SII]6716      4.534      0.14     -25    45
# Comp:  2             [SII]6731      3.196      0.14     -25    45
# Comp:  2              HeII4687     0.2019      0.14     -25    45
# Comp:  2               HeI5876     0.4491      0.14     -25    45
# Comp:  2          [OIII]5007_d      1.824      0.18     -25    45
# Comp:  2            [OI]6300_d     0.7902      0.18     -25    45
# Comp:  2           [NII]6583_d      12.05      0.18     -25    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        63
#  comp.  1:       -16        47
#  comp.  2:       -23        54
# chi2/DOF: 0.5930; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.366      0.14     -16    47
# Comp:  1                 Hbeta      6.266      0.14     -16    47
# Comp:  1                Halpha      25.63      0.14     -16    47
# Comp:  2             [SII]6716      4.688      0.14     -23    54
# Comp:  2             [SII]6731      3.409      0.14     -23    54
# Comp:  2              HeII4687      0.000      0.14     -23    54
# Comp:  2               HeI5876     0.6327      0.14     -23    54
# Comp:  2          [OIII]5007_d      2.017      0.18     -23    54
# Comp:  2            [OI]6300_d     0.8003      0.18     -23    54
# Comp:  2           [NII]6583_d      12.58      0.18     -23    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        89
#  comp.  1:       -18        49
#  comp.  2:       -22        52
# chi2/DOF: 0.5939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.591      0.14     -18    49
# Comp:  1                 Hbeta      4.685      0.14     -18    49
# Comp:  1                Halpha      26.20      0.14     -18    49
# Comp:  2             [SII]6716      4.706      0.14     -22    52
# Comp:  2             [SII]6731      3.229      0.14     -22    52
# Comp:  2              HeII4687    0.01318      0.14     -22    52
# Comp:  2               HeI5876     0.5262      0.14     -22    52
# Comp:  2          [OIII]5007_d      1.980      0.18     -22    52
# Comp:  2            [OI]6300_d     0.8668      0.18     -22    52
# Comp:  2           [NII]6583_d      12.42      0.18     -22    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        52
#  comp.  1:       -15        50
#  comp.  2:       -21        53
# chi2/DOF: 0.5794; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.568      0.14     -15    50
# Comp:  1                 Hbeta      6.075      0.14     -15    50
# Comp:  1                Halpha      26.14      0.14     -15    50
# Comp:  2             [SII]6716      4.704      0.14     -21    53
# Comp:  2             [SII]6731      3.381      0.14     -21    53
# Comp:  2              HeII4687      0.000      0.14     -21    53
# Comp:  2               HeI5876     0.6155      0.14     -21    53
# Comp:  2          [OIII]5007_d      2.138      0.18     -21    53
# Comp:  2            [OI]6300_d     0.8568      0.18     -21    53
# Comp:  2           [NII]6583_d      12.18      0.18     -21    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        87
#  comp.  1:       -16        51
#  comp.  2:       -22        50
# chi2/DOF: 0.6023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.073      0.14     -16    51
# Comp:  1                 Hbeta      5.803      0.14     -16    51
# Comp:  1                Halpha      26.73      0.14     -16    51
# Comp:  2             [SII]6716      4.647      0.14     -22    50
# Comp:  2             [SII]6731      3.368      0.14     -22    50
# Comp:  2              HeII4687      0.000      0.14     -22    50
# Comp:  2               HeI5876     0.4586      0.14     -22    50
# Comp:  2          [OIII]5007_d      2.176      0.18     -22    50
# Comp:  2            [OI]6300_d     0.8249      0.18     -22    50
# Comp:  2           [NII]6583_d      12.11      0.18     -22    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        78
#  comp.  1:       -19        50
#  comp.  2:       -25        45
# chi2/DOF: 0.5976; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.635      0.14     -19    50
# Comp:  1                 Hbeta      5.556      0.14     -19    50
# Comp:  1                Halpha      26.29      0.14     -19    50
# Comp:  2             [SII]6716      4.511      0.14     -25    45
# Comp:  2             [SII]6731      3.200      0.14     -25    45
# Comp:  2              HeII4687     0.1629      0.14     -25    45
# Comp:  2               HeI5876     0.5384      0.14     -25    45
# Comp:  2          [OIII]5007_d      1.946      0.18     -25    45
# Comp:  2            [OI]6300_d     0.7329      0.18     -25    45
# Comp:  2           [NII]6583_d      12.00      0.18     -25    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        57
#  comp.  1:       -17        48
#  comp.  2:       -25        50
# chi2/DOF: 0.5998; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.673      0.14     -17    48
# Comp:  1                 Hbeta      6.167      0.14     -17    48
# Comp:  1                Halpha      26.08      0.14     -17    48
# Comp:  2             [SII]6716      4.821      0.14     -25    50
# Comp:  2             [SII]6731      3.256      0.14     -25    50
# Comp:  2              HeII4687    0.01897      0.14     -25    50
# Comp:  2               HeI5876     0.7204      0.14     -25    50
# Comp:  2          [OIII]5007_d      1.797      0.18     -25    50
# Comp:  2            [OI]6300_d     0.8750      0.18     -25    50
# Comp:  2           [NII]6583_d      12.37      0.18     -25    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        85
#  comp.  1:       -16        50
#  comp.  2:       -24        49
# chi2/DOF: 0.6015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.089      0.14     -16    50
# Comp:  1                 Hbeta      5.161      0.14     -16    50
# Comp:  1                Halpha      26.39      0.14     -16    50
# Comp:  2             [SII]6716      4.648      0.14     -24    49
# Comp:  2             [SII]6731      3.234      0.14     -24    49
# Comp:  2              HeII4687     0.2182      0.14     -24    49
# Comp:  2               HeI5876     0.6009      0.14     -24    49
# Comp:  2          [OIII]5007_d      1.693      0.18     -24    49
# Comp:  2            [OI]6300_d     0.8348      0.18     -24    49
# Comp:  2           [NII]6583_d      12.48      0.18     -24    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        79
#  comp.  1:       -18        49
#  comp.  2:       -23        53
# chi2/DOF: 0.5832; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.501      0.14     -18    49
# Comp:  1                 Hbeta      6.719      0.14     -18    49
# Comp:  1                Halpha      26.41      0.14     -18    49
# Comp:  2             [SII]6716      4.777      0.14     -23    53
# Comp:  2             [SII]6731      3.254      0.14     -23    53
# Comp:  2              HeII4687    0.06257      0.14     -23    53
# Comp:  2               HeI5876     0.6091      0.14     -23    53
# Comp:  2          [OIII]5007_d      1.685      0.18     -23    53
# Comp:  2            [OI]6300_d     0.8467      0.18     -23    53
# Comp:  2           [NII]6583_d      12.56      0.18     -23    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        73
#  comp.  1:       -16        45
#  comp.  2:       -24        44
# chi2/DOF: 0.5864; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.525      0.14     -16    45
# Comp:  1                 Hbeta      5.035      0.14     -16    45
# Comp:  1                Halpha      25.56      0.14     -16    45
# Comp:  2             [SII]6716      4.639      0.14     -24    44
# Comp:  2             [SII]6731      3.165      0.14     -24    44
# Comp:  2              HeII4687      0.000      0.14     -24    44
# Comp:  2               HeI5876     0.5535      0.14     -24    44
# Comp:  2          [OIII]5007_d      1.966      0.18     -24    44
# Comp:  2            [OI]6300_d     0.8207      0.18     -24    44
# Comp:  2           [NII]6583_d      11.69      0.18     -24    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        89
#  comp.  1:       -16        46
#  comp.  2:       -24        46
# chi2/DOF: 0.5737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.590      0.14     -16    46
# Comp:  1                 Hbeta      4.816      0.14     -16    46
# Comp:  1                Halpha      25.59      0.14     -16    46
# Comp:  2             [SII]6716      4.635      0.14     -24    46
# Comp:  2             [SII]6731      3.324      0.14     -24    46
# Comp:  2              HeII4687     0.1859      0.14     -24    46
# Comp:  2               HeI5876     0.3628      0.14     -24    46
# Comp:  2          [OIII]5007_d      2.155      0.18     -24    46
# Comp:  2            [OI]6300_d     0.8141      0.18     -24    46
# Comp:  2           [NII]6583_d      11.98      0.18     -24    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        61
#  comp.  1:       -14        49
#  comp.  2:       -23        46
# chi2/DOF: 0.5976; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.193      0.14     -14    49
# Comp:  1                 Hbeta      6.186      0.14     -14    49
# Comp:  1                Halpha      25.94      0.14     -14    49
# Comp:  2             [SII]6716      4.571      0.14     -23    46
# Comp:  2             [SII]6731      3.277      0.14     -23    46
# Comp:  2              HeII4687     0.1449      0.14     -23    46
# Comp:  2               HeI5876     0.5288      0.14     -23    46
# Comp:  2          [OIII]5007_d      1.810      0.18     -23    46
# Comp:  2            [OI]6300_d     0.7786      0.18     -23    46
# Comp:  2           [NII]6583_d      11.96      0.18     -23    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        72
#  comp.  1:       -18        51
#  comp.  2:       -27        47
# chi2/DOF: 0.5795; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.651      0.14     -18    51
# Comp:  1                 Hbeta      6.471      0.14     -18    51
# Comp:  1                Halpha      26.19      0.14     -18    51
# Comp:  2             [SII]6716      4.533      0.14     -27    47
# Comp:  2             [SII]6731      3.107      0.14     -27    47
# Comp:  2              HeII4687    0.03816      0.14     -27    47
# Comp:  2               HeI5876     0.4552      0.14     -27    47
# Comp:  2          [OIII]5007_d      1.640      0.18     -27    47
# Comp:  2            [OI]6300_d     0.8299      0.18     -27    47
# Comp:  2           [NII]6583_d      12.14      0.18     -27    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        81
#  comp.  1:       -16        53
#  comp.  2:       -23        52
# chi2/DOF: 0.5865; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.499      0.14     -16    53
# Comp:  1                 Hbeta      6.381      0.14     -16    53
# Comp:  1                Halpha      26.60      0.14     -16    53
# Comp:  2             [SII]6716      4.682      0.14     -23    52
# Comp:  2             [SII]6731      3.269      0.14     -23    52
# Comp:  2              HeII4687   0.009517      0.14     -23    52
# Comp:  2               HeI5876     0.4730      0.14     -23    52
# Comp:  2          [OIII]5007_d      1.954      0.18     -23    52
# Comp:  2            [OI]6300_d     0.8297      0.18     -23    52
# Comp:  2           [NII]6583_d      12.26      0.18     -23    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        60
#  comp.  1:       -18        50
#  comp.  2:       -25        45
# chi2/DOF: 0.5892; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.620      0.14     -18    50
# Comp:  1                 Hbeta      6.409      0.14     -18    50
# Comp:  1                Halpha      26.24      0.14     -18    50
# Comp:  2             [SII]6716      4.515      0.14     -25    45
# Comp:  2             [SII]6731      3.176      0.14     -25    45
# Comp:  2              HeII4687      0.000      0.14     -25    45
# Comp:  2               HeI5876     0.5082      0.14     -25    45
# Comp:  2          [OIII]5007_d      2.165      0.18     -25    45
# Comp:  2            [OI]6300_d     0.8590      0.18     -25    45
# Comp:  2           [NII]6583_d      12.14      0.18     -25    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        73
#  comp.  1:       -14        51
#  comp.  2:       -21        55
# chi2/DOF: 0.5951; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.474      0.14     -14    51
# Comp:  1                 Hbeta      5.962      0.14     -14    51
# Comp:  1                Halpha      26.20      0.14     -14    51
# Comp:  2             [SII]6716      4.729      0.14     -21    55
# Comp:  2             [SII]6731      3.358      0.14     -21    55
# Comp:  2              HeII4687      0.000      0.14     -21    55
# Comp:  2               HeI5876     0.5927      0.14     -21    55
# Comp:  2          [OIII]5007_d      2.238      0.18     -21    55
# Comp:  2            [OI]6300_d     0.8297      0.18     -21    55
# Comp:  2           [NII]6583_d      12.44      0.18     -21    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        73
#  comp.  1:       -16        51
#  comp.  2:       -24        50
# chi2/DOF: 0.6054; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.848      0.14     -16    51
# Comp:  1                 Hbeta      5.974      0.14     -16    51
# Comp:  1                Halpha      26.68      0.14     -16    51
# Comp:  2             [SII]6716      4.554      0.14     -24    50
# Comp:  2             [SII]6731      3.240      0.14     -24    50
# Comp:  2              HeII4687      0.000      0.14     -24    50
# Comp:  2               HeI5876     0.5790      0.14     -24    50
# Comp:  2          [OIII]5007_d      2.111      0.18     -24    50
# Comp:  2            [OI]6300_d     0.8250      0.18     -24    50
# Comp:  2           [NII]6583_d      12.29      0.18     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        85
#  comp.  1:       -18        46
#  comp.  2:       -22        56
# chi2/DOF: 0.5838; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.865      0.14     -18    46
# Comp:  1                 Hbeta      5.102      0.14     -18    46
# Comp:  1                Halpha      26.15      0.14     -18    46
# Comp:  2             [SII]6716      4.923      0.14     -22    56
# Comp:  2             [SII]6731      3.324      0.14     -22    56
# Comp:  2              HeII4687     0.2181      0.14     -22    56
# Comp:  2               HeI5876     0.4993      0.14     -22    56
# Comp:  2          [OIII]5007_d      2.233      0.18     -22    56
# Comp:  2            [OI]6300_d     0.8848      0.18     -22    56
# Comp:  2           [NII]6583_d      12.68      0.18     -22    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        94
#  comp.  1:       -15        50
#  comp.  2:       -24        50
# chi2/DOF: 0.5945; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.803      0.14     -15    50
# Comp:  1                 Hbeta      5.055      0.14     -15    50
# Comp:  1                Halpha      26.01      0.14     -15    50
# Comp:  2             [SII]6716      4.678      0.14     -24    50
# Comp:  2             [SII]6731      3.314      0.14     -24    50
# Comp:  2              HeII4687    0.01248      0.14     -24    50
# Comp:  2               HeI5876     0.6024      0.14     -24    50
# Comp:  2          [OIII]5007_d      1.985      0.18     -24    50
# Comp:  2            [OI]6300_d     0.8050      0.18     -24    50
# Comp:  2           [NII]6583_d      12.28      0.18     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        84
#  comp.  1:       -16        48
#  comp.  2:       -24        45
# chi2/DOF: 0.5886; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.293      0.14     -16    48
# Comp:  1                 Hbeta      6.427      0.14     -16    48
# Comp:  1                Halpha      25.69      0.14     -16    48
# Comp:  2             [SII]6716      4.735      0.14     -24    45
# Comp:  2             [SII]6731      3.162      0.14     -24    45
# Comp:  2              HeII4687    0.04059      0.14     -24    45
# Comp:  2               HeI5876     0.5768      0.14     -24    45
# Comp:  2          [OIII]5007_d      1.739      0.18     -24    45
# Comp:  2            [OI]6300_d     0.8479      0.18     -24    45
# Comp:  2           [NII]6583_d      11.95      0.18     -24    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        68
#  comp.  1:       -18        51
#  comp.  2:       -24        50
# chi2/DOF: 0.5876; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.067      0.14     -18    51
# Comp:  1                 Hbeta      6.696      0.14     -18    51
# Comp:  1                Halpha      26.43      0.14     -18    51
# Comp:  2             [SII]6716      4.763      0.14     -24    50
# Comp:  2             [SII]6731      3.228      0.14     -24    50
# Comp:  2              HeII4687      0.000      0.14     -24    50
# Comp:  2               HeI5876     0.3082      0.14     -24    50
# Comp:  2          [OIII]5007_d      2.175      0.18     -24    50
# Comp:  2            [OI]6300_d     0.8949      0.18     -24    50
# Comp:  2           [NII]6583_d      12.35      0.18     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        73
#  comp.  1:       -14        50
#  comp.  2:       -23        47
# chi2/DOF: 0.5793; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.040      0.14     -14    50
# Comp:  1                 Hbeta      4.539      0.14     -14    50
# Comp:  1                Halpha      26.06      0.14     -14    50
# Comp:  2             [SII]6716      4.674      0.14     -23    47
# Comp:  2             [SII]6731      3.305      0.14     -23    47
# Comp:  2              HeII4687      0.000      0.14     -23    47
# Comp:  2               HeI5876     0.4162      0.14     -23    47
# Comp:  2          [OIII]5007_d      2.033      0.18     -23    47
# Comp:  2            [OI]6300_d     0.8775      0.18     -23    47
# Comp:  2           [NII]6583_d      11.81      0.18     -23    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        62
#  comp.  1:       -17        51
#  comp.  2:       -23        50
# chi2/DOF: 0.5862; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.339      0.14     -17    51
# Comp:  1                 Hbeta      4.942      0.14     -17    51
# Comp:  1                Halpha      26.81      0.14     -17    51
# Comp:  2             [SII]6716      4.636      0.14     -23    50
# Comp:  2             [SII]6731      3.274      0.14     -23    50
# Comp:  2              HeII4687    0.07685      0.14     -23    50
# Comp:  2               HeI5876     0.3612      0.14     -23    50
# Comp:  2          [OIII]5007_d      2.103      0.18     -23    50
# Comp:  2            [OI]6300_d     0.8159      0.18     -23    50
# Comp:  2           [NII]6583_d      12.45      0.18     -23    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        88
#  comp.  1:       -18        49
#  comp.  2:       -23        55
# chi2/DOF: 0.5830; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.407      0.14     -18    49
# Comp:  1                 Hbeta      6.374      0.14     -18    49
# Comp:  1                Halpha      26.10      0.14     -18    49
# Comp:  2             [SII]6716      4.768      0.14     -23    55
# Comp:  2             [SII]6731      3.394      0.14     -23    55
# Comp:  2              HeII4687     0.1557      0.14     -23    55
# Comp:  2               HeI5876     0.3669      0.14     -23    55
# Comp:  2          [OIII]5007_d      1.779      0.18     -23    55
# Comp:  2            [OI]6300_d     0.9252      0.18     -23    55
# Comp:  2           [NII]6583_d      12.63      0.18     -23    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        55
#  comp.  1:       -16        53
#  comp.  2:       -25        46
# chi2/DOF: 0.5922; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.235      0.14     -16    53
# Comp:  1                 Hbeta      6.418      0.14     -16    53
# Comp:  1                Halpha      26.91      0.14     -16    53
# Comp:  2             [SII]6716      4.484      0.14     -25    46
# Comp:  2             [SII]6731      3.297      0.14     -25    46
# Comp:  2              HeII4687      0.000      0.14     -25    46
# Comp:  2               HeI5876     0.6342      0.14     -25    46
# Comp:  2          [OIII]5007_d      1.818      0.18     -25    46
# Comp:  2            [OI]6300_d     0.8382      0.18     -25    46
# Comp:  2           [NII]6583_d      12.00      0.18     -25    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        78
#  comp.  1:       -17        48
#  comp.  2:       -24        51
# chi2/DOF: 0.6067; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.309      0.14     -17    48
# Comp:  1                 Hbeta      5.813      0.14     -17    48
# Comp:  1                Halpha      26.29      0.14     -17    48
# Comp:  2             [SII]6716      4.755      0.14     -24    51
# Comp:  2             [SII]6731      3.240      0.14     -24    51
# Comp:  2              HeII4687    0.09895      0.14     -24    51
# Comp:  2               HeI5876     0.5296      0.14     -24    51
# Comp:  2          [OIII]5007_d      2.040      0.18     -24    51
# Comp:  2            [OI]6300_d     0.8495      0.18     -24    51
# Comp:  2           [NII]6583_d      12.40      0.18     -24    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        90
#  comp.  1:       -17        44
#  comp.  2:       -24        44
# chi2/DOF: 0.5904; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.665      0.14     -17    44
# Comp:  1                 Hbeta      4.962      0.14     -17    44
# Comp:  1                Halpha      25.28      0.14     -17    44
# Comp:  2             [SII]6716      4.613      0.14     -24    44
# Comp:  2             [SII]6731      3.164      0.14     -24    44
# Comp:  2              HeII4687      0.000      0.14     -24    44
# Comp:  2               HeI5876     0.3891      0.14     -24    44
# Comp:  2          [OIII]5007_d      1.898      0.18     -24    44
# Comp:  2            [OI]6300_d     0.8165      0.18     -24    44
# Comp:  2           [NII]6583_d      11.92      0.18     -24    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        79
#  comp.  1:       -15        49
#  comp.  2:       -26        47
# chi2/DOF: 0.6004; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.598      0.14     -15    49
# Comp:  1                 Hbeta      5.250      0.14     -15    49
# Comp:  1                Halpha      25.83      0.14     -15    49
# Comp:  2             [SII]6716      4.504      0.14     -26    47
# Comp:  2             [SII]6731      3.207      0.14     -26    47
# Comp:  2              HeII4687     0.2158      0.14     -26    47
# Comp:  2               HeI5876     0.4963      0.14     -26    47
# Comp:  2          [OIII]5007_d      1.996      0.18     -26    47
# Comp:  2            [OI]6300_d     0.8661      0.18     -26    47
# Comp:  2           [NII]6583_d      12.26      0.18     -26    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        75
#  comp.  1:       -16        52
#  comp.  2:       -22        48
# chi2/DOF: 0.5924; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.690      0.14     -16    52
# Comp:  1                 Hbeta      6.117      0.14     -16    52
# Comp:  1                Halpha      26.44      0.14     -16    52
# Comp:  2             [SII]6716      4.598      0.14     -22    48
# Comp:  2             [SII]6731      3.286      0.14     -22    48
# Comp:  2              HeII4687    0.06153      0.14     -22    48
# Comp:  2               HeI5876     0.4230      0.14     -22    48
# Comp:  2          [OIII]5007_d      1.986      0.18     -22    48
# Comp:  2            [OI]6300_d     0.7750      0.18     -22    48
# Comp:  2           [NII]6583_d      11.94      0.18     -22    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        71
#  comp.  1:       -17        53
#  comp.  2:       -23        46
# chi2/DOF: 0.6027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.744      0.14     -17    53
# Comp:  1                 Hbeta      5.519      0.14     -17    53
# Comp:  1                Halpha      26.54      0.14     -17    53
# Comp:  2             [SII]6716      4.625      0.14     -23    46
# Comp:  2             [SII]6731      3.087      0.14     -23    46
# Comp:  2              HeII4687      0.000      0.14     -23    46
# Comp:  2               HeI5876     0.2977      0.14     -23    46
# Comp:  2          [OIII]5007_d      2.114      0.18     -23    46
# Comp:  2            [OI]6300_d     0.8742      0.18     -23    46
# Comp:  2           [NII]6583_d      12.11      0.18     -23    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        78
#  comp.  1:       -13        49
#  comp.  2:       -24        50
# chi2/DOF: 0.5986; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.165      0.14     -13    49
# Comp:  1                 Hbeta      6.042      0.14     -13    49
# Comp:  1                Halpha      26.08      0.14     -13    49
# Comp:  2             [SII]6716      4.612      0.14     -24    50
# Comp:  2             [SII]6731      3.146      0.14     -24    50
# Comp:  2              HeII4687      0.000      0.14     -24    50
# Comp:  2               HeI5876     0.5957      0.14     -24    50
# Comp:  2          [OIII]5007_d      1.890      0.18     -24    50
# Comp:  2            [OI]6300_d     0.8898      0.18     -24    50
# Comp:  2           [NII]6583_d      12.04      0.18     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        69
#  comp.  1:       -16        47
#  comp.  2:       -21        53
# chi2/DOF: 0.5931; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.675      0.14     -16    47
# Comp:  1                 Hbeta      6.041      0.14     -16    47
# Comp:  1                Halpha      25.51      0.14     -16    47
# Comp:  2             [SII]6716      4.749      0.14     -21    53
# Comp:  2             [SII]6731      3.244      0.14     -21    53
# Comp:  2              HeII4687    0.06010      0.14     -21    53
# Comp:  2               HeI5876     0.5645      0.14     -21    53
# Comp:  2          [OIII]5007_d      2.177      0.18     -21    53
# Comp:  2            [OI]6300_d     0.8308      0.18     -21    53
# Comp:  2           [NII]6583_d      12.52      0.18     -21    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        66
#  comp.  1:       -14        49
#  comp.  2:       -22        50
# chi2/DOF: 0.6004; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.034      0.14     -14    49
# Comp:  1                 Hbeta      5.099      0.14     -14    49
# Comp:  1                Halpha      26.07      0.14     -14    49
# Comp:  2             [SII]6716      4.671      0.14     -22    50
# Comp:  2             [SII]6731      3.247      0.14     -22    50
# Comp:  2              HeII4687     0.1463      0.14     -22    50
# Comp:  2               HeI5876     0.6924      0.14     -22    50
# Comp:  2          [OIII]5007_d      1.687      0.18     -22    50
# Comp:  2            [OI]6300_d     0.8153      0.18     -22    50
# Comp:  2           [NII]6583_d      12.29      0.18     -22    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        92
#  comp.  1:       -18        46
#  comp.  2:       -24        51
# chi2/DOF: 0.6032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.358      0.14     -18    46
# Comp:  1                 Hbeta      5.306      0.14     -18    46
# Comp:  1                Halpha      25.64      0.14     -18    46
# Comp:  2             [SII]6716      4.797      0.14     -24    51
# Comp:  2             [SII]6731      3.255      0.14     -24    51
# Comp:  2              HeII4687    0.06571      0.14     -24    51
# Comp:  2               HeI5876     0.4656      0.14     -24    51
# Comp:  2          [OIII]5007_d      1.923      0.18     -24    51
# Comp:  2            [OI]6300_d     0.8909      0.18     -24    51
# Comp:  2           [NII]6583_d      12.42      0.18     -24    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        84
#  comp.  1:       -17        52
#  comp.  2:       -23        47
# chi2/DOF: 0.5943; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.289      0.14     -17    52
# Comp:  1                 Hbeta      4.828      0.14     -17    52
# Comp:  1                Halpha      26.57      0.14     -17    52
# Comp:  2             [SII]6716      4.704      0.14     -23    47
# Comp:  2             [SII]6731      3.217      0.14     -23    47
# Comp:  2              HeII4687      0.000      0.14     -23    47
# Comp:  2               HeI5876     0.5298      0.14     -23    47
# Comp:  2          [OIII]5007_d      2.078      0.18     -23    47
# Comp:  2            [OI]6300_d     0.8354      0.18     -23    47
# Comp:  2           [NII]6583_d      12.00      0.18     -23    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        83
#  comp.  1:       -16        46
#  comp.  2:       -22        48
# chi2/DOF: 0.5843; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.315      0.14     -16    46
# Comp:  1                 Hbeta      4.657      0.14     -16    46
# Comp:  1                Halpha      25.63      0.14     -16    46
# Comp:  2             [SII]6716      4.697      0.14     -22    48
# Comp:  2             [SII]6731      3.286      0.14     -22    48
# Comp:  2              HeII4687     0.1686      0.14     -22    48
# Comp:  2               HeI5876     0.4828      0.14     -22    48
# Comp:  2          [OIII]5007_d      2.031      0.18     -22    48
# Comp:  2            [OI]6300_d     0.7826      0.18     -22    48
# Comp:  2           [NII]6583_d      11.98      0.18     -22    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        71
#  comp.  1:       -16        51
#  comp.  2:       -24        45
# chi2/DOF: 0.6048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        63
#  comp.  1:       -17        45
#  comp.  2:       -23        47
# chi2/DOF: 0.6006; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.616      0.14     -17    45
# Comp:  1                 Hbeta      5.429      0.14     -17    45
# Comp:  1                Halpha      25.56      0.14     -17    45
# Comp:  2             [SII]6716      4.733      0.14     -23    47
# Comp:  2             [SII]6731      3.189      0.14     -23    47
# Comp:  2              HeII4687  0.0003490      0.14     -23    47
# Comp:  2               HeI5876     0.4629      0.14     -23    47
# Comp:  2          [OIII]5007_d      2.041      0.18     -23    47
# Comp:  2            [OI]6300_d     0.7718      0.18     -23    47
# Comp:  2           [NII]6583_d      11.92      0.18     -23    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        80
#  comp.  1:       -18        51
#  comp.  2:       -24        48
# chi2/DOF: 0.6043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.702      0.14     -18    51
# Comp:  1                 Hbeta      5.223      0.14     -18    51
# Comp:  1                Halpha      26.63      0.14     -18    51
# Comp:  2             [SII]6716      4.615      0.14     -24    48
# Comp:  2             [SII]6731      3.224      0.14     -24    48
# Comp:  2              HeII4687    0.08570      0.14     -24    48
# Comp:  2               HeI5876     0.7060      0.14     -24    48
# Comp:  2          [OIII]5007_d      2.079      0.18     -24    48
# Comp:  2            [OI]6300_d     0.8087      0.18     -24    48
# Comp:  2           [NII]6583_d      12.11      0.18     -24    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        73
#  comp.  1:       -15        50
#  comp.  2:       -23        49
# chi2/DOF: 0.5889; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.538      0.14     -15    50
# Comp:  1                 Hbeta      4.717      0.14     -15    50
# Comp:  1                Halpha      25.95      0.14     -15    50
# Comp:  2             [SII]6716      4.665      0.14     -23    49
# Comp:  2             [SII]6731      3.205      0.14     -23    49
# Comp:  2              HeII4687    0.03948      0.14     -23    49
# Comp:  2               HeI5876     0.3794      0.14     -23    49
# Comp:  2          [OIII]5007_d      1.875      0.18     -23    49
# Comp:  2            [OI]6300_d     0.8250      0.18     -23    49
# Comp:  2           [NII]6583_d      12.14      0.18     -23    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        79
#  comp.  1:       -16        50
#  comp.  2:       -21        51
# chi2/DOF: 0.6053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.255      0.14     -16    50
# Comp:  1                 Hbeta      5.523      0.14     -16    50
# Comp:  1                Halpha      26.12      0.14     -16    50
# Comp:  2             [SII]6716      4.756      0.14     -21    51
# Comp:  2             [SII]6731      3.108      0.14     -21    51
# Comp:  2              HeII4687      0.000      0.14     -21    51
# Comp:  2               HeI5876     0.6611      0.14     -21    51
# Comp:  2          [OIII]5007_d      1.969      0.18     -21    51
# Comp:  2            [OI]6300_d     0.7954      0.18     -21    51
# Comp:  2           [NII]6583_d      12.22      0.18     -21    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        80
#  comp.  1:       -17        46
#  comp.  2:       -25        45
# chi2/DOF: 0.6017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.867      0.14     -17    46
# Comp:  1                 Hbeta      4.981      0.14     -17    46
# Comp:  1                Halpha      25.68      0.14     -17    46
# Comp:  2             [SII]6716      4.558      0.14     -25    45
# Comp:  2             [SII]6731      3.019      0.14     -25    45
# Comp:  2              HeII4687     0.1378      0.14     -25    45
# Comp:  2               HeI5876     0.4290      0.14     -25    45
# Comp:  2          [OIII]5007_d      1.989      0.18     -25    45
# Comp:  2            [OI]6300_d     0.7108      0.18     -25    45
# Comp:  2           [NII]6583_d      12.07      0.18     -25    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        54
#  comp.  1:       -18        51
#  comp.  2:       -25        50
# chi2/DOF: 0.5958; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.457      0.14     -18    51
# Comp:  1                 Hbeta      4.844      0.14     -18    51
# Comp:  1                Halpha      26.38      0.14     -18    51
# Comp:  2             [SII]6716      4.681      0.14     -25    50
# Comp:  2             [SII]6731      3.270      0.14     -25    50
# Comp:  2              HeII4687      0.000      0.14     -25    50
# Comp:  2               HeI5876     0.6669      0.14     -25    50
# Comp:  2          [OIII]5007_d      1.739      0.18     -25    50
# Comp:  2            [OI]6300_d     0.8441      0.18     -25    50
# Comp:  2           [NII]6583_d      12.23      0.18     -25    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        68
#  comp.  1:       -15        51
#  comp.  2:       -21        55
# chi2/DOF: 0.5704; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.827      0.14     -15    51
# Comp:  1                 Hbeta      6.635      0.14     -15    51
# Comp:  1                Halpha      26.04      0.14     -15    51
# Comp:  2             [SII]6716      4.857      0.14     -21    55
# Comp:  2             [SII]6731      3.213      0.14     -21    55
# Comp:  2              HeII4687     0.1858      0.14     -21    55
# Comp:  2               HeI5876     0.7556      0.14     -21    55
# Comp:  2          [OIII]5007_d      2.102      0.18     -21    55
# Comp:  2            [OI]6300_d     0.8506      0.18     -21    55
# Comp:  2           [NII]6583_d      12.27      0.18     -21    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        90
#  comp.  1:       -14        51
#  comp.  2:       -23        48
# chi2/DOF: 0.5903; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.334      0.14     -14    51
# Comp:  1                 Hbeta      6.447      0.14     -14    51
# Comp:  1                Halpha      26.39      0.14     -14    51
# Comp:  2             [SII]6716      4.642      0.14     -23    48
# Comp:  2             [SII]6731      3.206      0.14     -23    48
# Comp:  2              HeII4687     0.1923      0.14     -23    48
# Comp:  2               HeI5876     0.5177      0.14     -23    48
# Comp:  2          [OIII]5007_d      1.867      0.18     -23    48
# Comp:  2            [OI]6300_d     0.8160      0.18     -23    48
# Comp:  2           [NII]6583_d      11.94      0.18     -23    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        87
#  comp.  1:       -15        53
#  comp.  2:       -24        50
# chi2/DOF: 0.5681; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.370      0.14     -15    53
# Comp:  1                 Hbeta      6.395      0.14     -15    53
# Comp:  1                Halpha      26.10      0.14     -15    53
# Comp:  2             [SII]6716      4.622      0.14     -24    50
# Comp:  2             [SII]6731      3.129      0.14     -24    50
# Comp:  2              HeII4687      0.000      0.14     -24    50
# Comp:  2               HeI5876     0.4865      0.14     -24    50
# Comp:  2          [OIII]5007_d      2.114      0.18     -24    50
# Comp:  2            [OI]6300_d     0.7981      0.18     -24    50
# Comp:  2           [NII]6583_d      12.28      0.18     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        92
#  comp.  1:       -18        50
#  comp.  2:       -21        53
# chi2/DOF: 0.5852; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.106      0.14     -18    50
# Comp:  1                 Hbeta      6.472      0.14     -18    50
# Comp:  1                Halpha      26.22      0.14     -18    50
# Comp:  2             [SII]6716      4.707      0.14     -21    53
# Comp:  2             [SII]6731      3.360      0.14     -21    53
# Comp:  2              HeII4687      0.000      0.14     -21    53
# Comp:  2               HeI5876     0.6870      0.14     -21    53
# Comp:  2          [OIII]5007_d      1.930      0.18     -21    53
# Comp:  2            [OI]6300_d     0.9059      0.18     -21    53
# Comp:  2           [NII]6583_d      12.44      0.18     -21    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        89
#  comp.  1:       -18        49
#  comp.  2:       -23        50
# chi2/DOF: 0.5958; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.265      0.14     -18    49
# Comp:  1                 Hbeta      6.389      0.14     -18    49
# Comp:  1                Halpha      26.39      0.14     -18    49
# Comp:  2             [SII]6716      4.533      0.14     -23    50
# Comp:  2             [SII]6731      3.230      0.14     -23    50
# Comp:  2              HeII4687      0.000      0.14     -23    50
# Comp:  2               HeI5876     0.5657      0.14     -23    50
# Comp:  2          [OIII]5007_d      1.897      0.18     -23    50
# Comp:  2            [OI]6300_d     0.8094      0.18     -23    50
# Comp:  2           [NII]6583_d      12.31      0.18     -23    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        65
#  comp.  1:       -18        47
#  comp.  2:       -24        54
# chi2/DOF: 0.5818; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.472      0.14     -18    47
# Comp:  1                 Hbeta      4.734      0.14     -18    47
# Comp:  1                Halpha      26.14      0.14     -18    47
# Comp:  2             [SII]6716      4.788      0.14     -24    54
# Comp:  2             [SII]6731      3.304      0.14     -24    54
# Comp:  2              HeII4687      0.000      0.14     -24    54
# Comp:  2               HeI5876     0.4849      0.14     -24    54
# Comp:  2          [OIII]5007_d      1.733      0.18     -24    54
# Comp:  2            [OI]6300_d     0.8219      0.18     -24    54
# Comp:  2           [NII]6583_d      12.31      0.18     -24    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        75
#  comp.  1:       -15        50
#  comp.  2:       -25        51
# chi2/DOF: 0.5998; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.251      0.14     -15    50
# Comp:  1                 Hbeta      5.176      0.14     -15    50
# Comp:  1                Halpha      26.23      0.14     -15    50
# Comp:  2             [SII]6716      4.742      0.14     -25    51
# Comp:  2             [SII]6731      3.152      0.14     -25    51
# Comp:  2              HeII4687      0.000      0.14     -25    51
# Comp:  2               HeI5876     0.3409      0.14     -25    51
# Comp:  2          [OIII]5007_d      2.039      0.18     -25    51
# Comp:  2            [OI]6300_d     0.8395      0.18     -25    51
# Comp:  2           [NII]6583_d      12.31      0.18     -25    51
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.34835267, 0.57162122, 0.52458192, 0.1188913 , 0.12152471,
#        0.07785702, 0.14402656, 0.18242368, 0.05471175, 0.30496657])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_10_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_10", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_10_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_10_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_10_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
