# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/FIRST-J110949.3+124614_2_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/FIRST-J110949.3+124614_2_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     361   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        42   (2094, 964)   float32

# %%
image_cut = image[49:149, 0:1890]
image_error_cut = image_error[49:149, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.04263
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
sigma = 2.380 / 2.35
n_component = 5

# %%
l_HA
# Out:
# 6842.78069

# %% [markdown]
# ## Continuum

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/FIRST-J110949.3+124614_2_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[49:149, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/FIRST-J110949.3+124614_2_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     361   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        42   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 15)*(y < 25)
mask_wv = wv > 4400
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)
#x_interval = np.arange(4300, 4300+1800*1.48, 250)
#plt.xticks(x_interval)
plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) #+
       # sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs):
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
   # ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(r"Radial profile H$\alpha$")
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 10.5)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(r"Radial profile H$\alpha$")
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 10.5)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
# Bounds:
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (45, 60),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (47, 55),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 62),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (77, 85)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 160.20778375083123
# differential_evolution step 2: f(x)= 160.20778375083123
# differential_evolution step 3: f(x)= 150.6981004475745
# differential_evolution step 4: f(x)= 133.7114515795533
# differential_evolution step 5: f(x)= 133.7114515795533
# differential_evolution step 6: f(x)= 116.1951458450866
# differential_evolution step 7: f(x)= 113.01594367182717
# differential_evolution step 8: f(x)= 102.21393220689107
# differential_evolution step 9: f(x)= 100.30851726267932
# differential_evolution step 10: f(x)= 97.1878601661187
# differential_evolution step 11: f(x)= 97.1878601661187
# differential_evolution step 12: f(x)= 97.1878601661187
# differential_evolution step 13: f(x)= 97.1878601661187
# differential_evolution step 14: f(x)= 97.1878601661187
# differential_evolution step 15: f(x)= 97.1878601661187
# differential_evolution step 16: f(x)= 96.52911457615377
# differential_evolution step 17: f(x)= 91.56034931129382
# differential_evolution step 18: f(x)= 91.56034931129382
# differential_evolution step 19: f(x)= 91.56034931129382
# differential_evolution step 20: f(x)= 91.56034931129382
# differential_evolution step 21: f(x)= 85.78155388883589
# differential_evolution step 22: f(x)= 85.78155388883589
# differential_evolution step 23: f(x)= 81.42895029065976
# differential_evolution step 24: f(x)= 80.0897298000534
# differential_evolution step 25: f(x)= 80.0897298000534
# differential_evolution step 26: f(x)= 80.0897298000534
# differential_evolution step 27: f(x)= 80.0897298000534
# differential_evolution step 28: f(x)= 78.49510080504136
# differential_evolution step 29: f(x)= 78.49510080504136
# differential_evolution step 30: f(x)= 78.49510080504136
# differential_evolution step 31: f(x)= 78.49510080504136
# differential_evolution step 32: f(x)= 73.86435824785578
# differential_evolution step 33: f(x)= 73.86435824785578
# differential_evolution step 34: f(x)= 73.86435824785578
# differential_evolution step 35: f(x)= 73.86435824785578
# differential_evolution step 36: f(x)= 73.86435824785578
# differential_evolution step 37: f(x)= 73.86435824785578
# differential_evolution step 38: f(x)= 73.86435824785578
# differential_evolution step 39: f(x)= 73.86435824785578
# differential_evolution step 40: f(x)= 73.86435824785578
# differential_evolution step 41: f(x)= 73.86435824785578
# differential_evolution step 42: f(x)= 73.86435824785578
# differential_evolution step 43: f(x)= 71.67465367835315
# differential_evolution step 44: f(x)= 71.67465367835315
# differential_evolution step 45: f(x)= 71.67465367835315
# differential_evolution step 46: f(x)= 71.67465367835315
# differential_evolution step 47: f(x)= 71.08154183905042
# differential_evolution step 48: f(x)= 70.26297302647151
# differential_evolution step 49: f(x)= 70.26297302647151
# differential_evolution step 50: f(x)= 70.26297302647151
# differential_evolution step 51: f(x)= 70.26297302647151
# differential_evolution step 52: f(x)= 70.26297302647151
# differential_evolution step 53: f(x)= 70.26297302647151
# differential_evolution step 54: f(x)= 70.26297302647151
# differential_evolution step 55: f(x)= 70.26297302647151
# differential_evolution step 56: f(x)= 70.26297302647151
# differential_evolution step 57: f(x)= 70.26297302647151
# differential_evolution step 58: f(x)= 70.26297302647151
# differential_evolution step 59: f(x)= 70.26297302647151
# differential_evolution step 60: f(x)= 70.26297302647151
# differential_evolution step 61: f(x)= 65.35424074570453
# differential_evolution step 62: f(x)= 65.35424074570453
# differential_evolution step 63: f(x)= 65.35424074570453
# differential_evolution step 64: f(x)= 65.35424074570453
# differential_evolution step 65: f(x)= 65.35424074570453
# differential_evolution step 66: f(x)= 65.35424074570453
# differential_evolution step 67: f(x)= 65.35424074570453
# differential_evolution step 68: f(x)= 65.35424074570453
# differential_evolution step 69: f(x)= 65.35424074570453
# differential_evolution step 70: f(x)= 65.35424074570453
# differential_evolution step 71: f(x)= 65.35424074570453
# differential_evolution step 72: f(x)= 65.35424074570453
# differential_evolution step 73: f(x)= 65.35424074570453
# differential_evolution step 74: f(x)= 65.35424074570453
# differential_evolution step 75: f(x)= 65.35424074570453
# differential_evolution step 76: f(x)= 65.35424074570453
# differential_evolution step 77: f(x)= 65.35424074570453
# differential_evolution step 78: f(x)= 65.35424074570453
# differential_evolution step 79: f(x)= 65.35424074570453
# differential_evolution step 80: f(x)= 65.35424074570453
# differential_evolution step 81: f(x)= 65.35424074570453
# differential_evolution step 82: f(x)= 64.97902422637715
# differential_evolution step 83: f(x)= 64.97902422637715
# differential_evolution step 84: f(x)= 63.98235863348287
# differential_evolution step 85: f(x)= 63.98235863348287
# differential_evolution step 86: f(x)= 63.98235863348287
# differential_evolution step 87: f(x)= 63.98235863348287
# differential_evolution step 88: f(x)= 60.347689235682225
# differential_evolution step 89: f(x)= 60.347689235682225
# differential_evolution step 90: f(x)= 60.347689235682225
# differential_evolution step 91: f(x)= 60.347689235682225
# differential_evolution step 92: f(x)= 60.347689235682225
# differential_evolution step 93: f(x)= 60.347689235682225
# differential_evolution step 94: f(x)= 60.347689235682225
# differential_evolution step 95: f(x)= 60.347689235682225
# differential_evolution step 96: f(x)= 60.347689235682225
# differential_evolution step 97: f(x)= 60.347689235682225
# differential_evolution step 98: f(x)= 60.347689235682225
# differential_evolution step 99: f(x)= 60.347689235682225
# differential_evolution step 100: f(x)= 60.347689235682225
# differential_evolution step 101: f(x)= 60.347689235682225
# differential_evolution step 102: f(x)= 60.347689235682225
# differential_evolution step 103: f(x)= 60.347689235682225
# differential_evolution step 104: f(x)= 60.347689235682225
# differential_evolution step 105: f(x)= 60.347689235682225
# differential_evolution step 106: f(x)= 60.347689235682225
# differential_evolution step 107: f(x)= 60.347689235682225
# differential_evolution step 108: f(x)= 59.58221072082616
# differential_evolution step 109: f(x)= 59.58221072082616
# differential_evolution step 110: f(x)= 59.58221072082616
# differential_evolution step 111: f(x)= 59.58221072082616
# differential_evolution step 112: f(x)= 59.58221072082616
# differential_evolution step 113: f(x)= 59.58221072082616
# differential_evolution step 114: f(x)= 59.58221072082616
# differential_evolution step 115: f(x)= 59.58221072082616
# differential_evolution step 116: f(x)= 59.58221072082616
# differential_evolution step 117: f(x)= 59.58221072082616
# differential_evolution step 118: f(x)= 59.58221072082616
# differential_evolution step 119: f(x)= 59.40753824004238
# differential_evolution step 120: f(x)= 59.40753824004238
# differential_evolution step 121: f(x)= 59.40753824004238
# differential_evolution step 122: f(x)= 59.40753824004238
# differential_evolution step 123: f(x)= 59.40753824004238
# differential_evolution step 124: f(x)= 59.40753824004238
# differential_evolution step 125: f(x)= 59.40753824004238
# differential_evolution step 126: f(x)= 59.40753824004238
# differential_evolution step 127: f(x)= 59.40753824004238
# differential_evolution step 128: f(x)= 58.60781957390122
# differential_evolution step 129: f(x)= 58.60781957390122
# differential_evolution step 130: f(x)= 58.03047238498111
# differential_evolution step 131: f(x)= 58.03047238498111
# differential_evolution step 132: f(x)= 58.03047238498111
# differential_evolution step 133: f(x)= 58.03047238498111
# differential_evolution step 134: f(x)= 58.03047238498111
# differential_evolution step 135: f(x)= 58.03047238498111
# differential_evolution step 136: f(x)= 58.03047238498111
# differential_evolution step 137: f(x)= 58.03047238498111
# differential_evolution step 138: f(x)= 58.03047238498111
# differential_evolution step 139: f(x)= 58.03047238498111
# differential_evolution step 140: f(x)= 58.03047238498111
# differential_evolution step 141: f(x)= 58.03047238498111
# differential_evolution step 142: f(x)= 58.03047238498111
# differential_evolution step 143: f(x)= 58.03047238498111
# differential_evolution step 144: f(x)= 58.03047238498111
# differential_evolution step 145: f(x)= 58.03047238498111
# differential_evolution step 146: f(x)= 58.03047238498111
# differential_evolution step 147: f(x)= 58.03047238498111
# differential_evolution step 148: f(x)= 58.03047238498111
# differential_evolution step 149: f(x)= 58.03047238498111
# differential_evolution step 150: f(x)= 58.03047238498111
# differential_evolution step 151: f(x)= 58.03047238498111
# differential_evolution step 152: f(x)= 58.03047238498111
# differential_evolution step 153: f(x)= 57.76443265633469
# differential_evolution step 154: f(x)= 57.76443265633469
# differential_evolution step 155: f(x)= 57.666459490533484
# differential_evolution step 156: f(x)= 57.666459490533484
# differential_evolution step 157: f(x)= 57.666459490533484
# differential_evolution step 158: f(x)= 57.666459490533484
# differential_evolution step 159: f(x)= 57.666459490533484
# differential_evolution step 160: f(x)= 57.666459490533484
# differential_evolution step 161: f(x)= 57.666459490533484
# differential_evolution step 162: f(x)= 57.59914253963211
# differential_evolution step 163: f(x)= 57.59914253963211
# differential_evolution step 164: f(x)= 57.59914253963211
# differential_evolution step 165: f(x)= 57.59914253963211
# differential_evolution step 166: f(x)= 57.59914253963211
# differential_evolution step 167: f(x)= 57.52764019256707
# differential_evolution step 168: f(x)= 57.52764019256707
# differential_evolution step 169: f(x)= 57.47196279999036
# differential_evolution step 170: f(x)= 57.47196279999036
# differential_evolution step 171: f(x)= 57.47196279999036
# differential_evolution step 172: f(x)= 57.47196279999036
# differential_evolution step 173: f(x)= 57.47196279999036
# differential_evolution step 174: f(x)= 57.36394654424061
# differential_evolution step 175: f(x)= 57.36394654424061
# differential_evolution step 176: f(x)= 57.36394654424061
# differential_evolution step 177: f(x)= 57.36394654424061
# differential_evolution step 178: f(x)= 57.36394654424061
# differential_evolution step 179: f(x)= 57.13829827593408
# differential_evolution step 180: f(x)= 57.13829827593408
# differential_evolution step 181: f(x)= 57.13829827593408
# differential_evolution step 182: f(x)= 57.13829827593408
# differential_evolution step 183: f(x)= 57.13829827593408
# differential_evolution step 184: f(x)= 57.13829827593408
# differential_evolution step 185: f(x)= 57.13829827593408
# differential_evolution step 186: f(x)= 57.006392179049826
# differential_evolution step 187: f(x)= 57.006392179049826
# differential_evolution step 188: f(x)= 57.006392179049826
# differential_evolution step 189: f(x)= 56.91492469250608
# differential_evolution step 190: f(x)= 56.721637456888466
# differential_evolution step 191: f(x)= 56.721637456888466
# differential_evolution step 192: f(x)= 56.721637456888466
# differential_evolution step 193: f(x)= 56.68201604402964
# differential_evolution step 194: f(x)= 56.68201604402964
# differential_evolution step 195: f(x)= 56.68201604402964
# differential_evolution step 196: f(x)= 56.68201604402964
# differential_evolution step 197: f(x)= 56.50651408404309
# differential_evolution step 198: f(x)= 56.50651408404309
# differential_evolution step 199: f(x)= 56.50651408404309
# differential_evolution step 200: f(x)= 56.50651408404309
# differential_evolution step 201: f(x)= 56.50651408404309
# differential_evolution step 202: f(x)= 56.50651408404309
# differential_evolution step 203: f(x)= 56.50651408404309
# differential_evolution step 204: f(x)= 56.50651408404309
# differential_evolution step 205: f(x)= 56.50651408404309
# differential_evolution step 206: f(x)= 56.50651408404309
# differential_evolution step 207: f(x)= 56.50651408404309
# differential_evolution step 208: f(x)= 56.50651408404309
# differential_evolution step 209: f(x)= 56.50651408404309
# differential_evolution step 210: f(x)= 56.50651408404309
# differential_evolution step 211: f(x)= 56.50651408404309
# differential_evolution step 212: f(x)= 56.50651408404309
# differential_evolution step 213: f(x)= 56.50651408404309
# differential_evolution step 214: f(x)= 56.37496791682668
# differential_evolution step 215: f(x)= 56.37496791682668
# differential_evolution step 216: f(x)= 56.37496791682668
# differential_evolution step 217: f(x)= 56.37496791682668
# differential_evolution step 218: f(x)= 56.37496791682668
# differential_evolution step 219: f(x)= 56.37496791682668
# differential_evolution step 220: f(x)= 56.37496791682668
# differential_evolution step 221: f(x)= 56.37496791682668
# differential_evolution step 222: f(x)= 56.37496791682668
# differential_evolution step 223: f(x)= 56.32180349851432
# differential_evolution step 224: f(x)= 56.32180349851432
# differential_evolution step 225: f(x)= 56.24286681159001
# differential_evolution step 226: f(x)= 56.21663113331358
# differential_evolution step 227: f(x)= 56.16770105235734
# differential_evolution step 228: f(x)= 56.088541182586
# differential_evolution step 229: f(x)= 55.963980587513504
# differential_evolution step 230: f(x)= 55.92921814383673
# differential_evolution step 231: f(x)= 55.92921814383673
# differential_evolution step 232: f(x)= 55.85655989355388
# differential_evolution step 233: f(x)= 55.85655989355388
# differential_evolution step 234: f(x)= 55.85655989355388
# differential_evolution step 235: f(x)= 55.85655989355388
# differential_evolution step 236: f(x)= 55.85655989355388
# differential_evolution step 237: f(x)= 55.85655989355388
# differential_evolution step 238: f(x)= 55.85655989355388
# differential_evolution step 239: f(x)= 55.85655989355388
# differential_evolution step 240: f(x)= 55.84960991464319
# differential_evolution step 241: f(x)= 55.69357387287664
# differential_evolution step 242: f(x)= 55.69357387287664
# differential_evolution step 243: f(x)= 55.6787238165589
# differential_evolution step 244: f(x)= 55.6787238165589
# differential_evolution step 245: f(x)= 55.6787238165589
# differential_evolution step 246: f(x)= 55.6787238165589
# differential_evolution step 247: f(x)= 55.6787238165589
# differential_evolution step 248: f(x)= 55.6787238165589
# differential_evolution step 249: f(x)= 55.6787238165589
# differential_evolution step 250: f(x)= 55.6787238165589
# differential_evolution step 251: f(x)= 55.6787238165589
# differential_evolution step 252: f(x)= 55.66194943764357
# differential_evolution step 253: f(x)= 55.64133731395918
# differential_evolution step 254: f(x)= 55.64133731395918
# differential_evolution step 255: f(x)= 55.64133731395918
# differential_evolution step 256: f(x)= 55.64133731395918
# differential_evolution step 257: f(x)= 55.61784073502252
# differential_evolution step 258: f(x)= 55.61784073502252
# differential_evolution step 259: f(x)= 55.61784073502252
# differential_evolution step 260: f(x)= 55.61784073502252
# differential_evolution step 261: f(x)= 55.61147992263081
# differential_evolution step 262: f(x)= 55.61147992263081
# differential_evolution step 263: f(x)= 55.61147992263081
# differential_evolution step 264: f(x)= 55.61147992263081
# differential_evolution step 265: f(x)= 55.61147992263081
# differential_evolution step 266: f(x)= 55.61147992263081
# differential_evolution step 267: f(x)= 55.560518941389205
# differential_evolution step 268: f(x)= 55.560518941389205
# differential_evolution step 269: f(x)= 55.560518941389205
# differential_evolution step 270: f(x)= 55.560518941389205
# differential_evolution step 271: f(x)= 55.560518941389205
# differential_evolution step 272: f(x)= 55.53195916727281
# differential_evolution step 273: f(x)= 55.53195916727281
# differential_evolution step 274: f(x)= 55.53195916727281
# differential_evolution step 275: f(x)= 55.53195916727281
# differential_evolution step 276: f(x)= 55.53195916727281
# differential_evolution step 277: f(x)= 55.53195916727281
# differential_evolution step 278: f(x)= 55.53195916727281
# differential_evolution step 279: f(x)= 55.53195916727281
# differential_evolution step 280: f(x)= 55.53195916727281
# differential_evolution step 281: f(x)= 55.53195916727281
# differential_evolution step 282: f(x)= 55.53195916727281
# differential_evolution step 283: f(x)= 55.53195916727281
# differential_evolution step 284: f(x)= 55.512009174741046
# differential_evolution step 285: f(x)= 55.512009174741046
# differential_evolution step 286: f(x)= 55.511992070317426
# differential_evolution step 287: f(x)= 55.511992070317426
# differential_evolution step 288: f(x)= 55.50042187225194
# differential_evolution step 289: f(x)= 55.50042187225194
# differential_evolution step 290: f(x)= 55.50042187225194
# differential_evolution step 291: f(x)= 55.50042187225194
# differential_evolution step 292: f(x)= 55.50042187225194
# differential_evolution step 293: f(x)= 55.49936765704187
# differential_evolution step 294: f(x)= 55.48036343763549
# differential_evolution step 295: f(x)= 55.48036343763549
# differential_evolution step 296: f(x)= 55.48036343763549
# differential_evolution step 297: f(x)= 55.47812243852525
# differential_evolution step 298: f(x)= 55.47812243852525
# differential_evolution step 299: f(x)= 55.47812243852525
# differential_evolution step 300: f(x)= 55.47812243852525
# differential_evolution step 301: f(x)= 55.47812243852525
# differential_evolution step 302: f(x)= 55.47812243852525
# differential_evolution step 303: f(x)= 55.47812243852525
# differential_evolution step 304: f(x)= 55.47812243852525
# differential_evolution step 305: f(x)= 55.47812243852525
# differential_evolution step 306: f(x)= 55.476868774939604
# differential_evolution step 307: f(x)= 55.476868774939604
# differential_evolution step 308: f(x)= 55.476868774939604
# differential_evolution step 309: f(x)= 55.476868774939604
# differential_evolution step 310: f(x)= 55.47664545010732
# differential_evolution step 311: f(x)= 55.47664545010732
# differential_evolution step 312: f(x)= 55.45186523255407
# differential_evolution step 313: f(x)= 55.45153760775069
# differential_evolution step 314: f(x)= 55.44894389559036
# differential_evolution step 315: f(x)= 55.44894389559036
# differential_evolution step 316: f(x)= 55.44894389559036
# differential_evolution step 317: f(x)= 55.44894389559036
# differential_evolution step 318: f(x)= 55.44894389559036
# differential_evolution step 319: f(x)= 55.44894389559036
# differential_evolution step 320: f(x)= 55.44894389559036
# differential_evolution step 321: f(x)= 55.43163641285768
# differential_evolution step 322: f(x)= 55.43163641285768
# differential_evolution step 323: f(x)= 55.43163641285768
# differential_evolution step 324: f(x)= 55.40566384901364
# differential_evolution step 325: f(x)= 55.391996170608124
# differential_evolution step 326: f(x)= 55.391996170608124
# differential_evolution step 327: f(x)= 55.389075614343895
# differential_evolution step 328: f(x)= 55.389075614343895
# differential_evolution step 329: f(x)= 55.389075614343895
# differential_evolution step 330: f(x)= 55.383358634210964
# differential_evolution step 331: f(x)= 55.38182632039337
# differential_evolution step 332: f(x)= 55.38182632039337
# differential_evolution step 333: f(x)= 55.355506285106046
# differential_evolution step 334: f(x)= 55.355506285106046
# differential_evolution step 335: f(x)= 55.355506285106046
# differential_evolution step 336: f(x)= 55.32375678781924
# differential_evolution step 337: f(x)= 55.32375678781924
# differential_evolution step 338: f(x)= 55.32375678781924
# differential_evolution step 339: f(x)= 55.314537792399285
# differential_evolution step 340: f(x)= 55.314537792399285
# differential_evolution step 341: f(x)= 55.30108655961217
# differential_evolution step 342: f(x)= 55.30108655961217
# differential_evolution step 343: f(x)= 55.30108655961217
# differential_evolution step 344: f(x)= 55.30068176816674
# differential_evolution step 345: f(x)= 55.30068176816674
# differential_evolution step 346: f(x)= 55.292808736504384
# differential_evolution step 347: f(x)= 55.28358467770072
# differential_evolution step 348: f(x)= 55.28358467770072
# differential_evolution step 349: f(x)= 55.28358467770072
# differential_evolution step 350: f(x)= 55.28358467770072
# differential_evolution step 351: f(x)= 55.28358467770072
# differential_evolution step 352: f(x)= 55.28358467770072
# differential_evolution step 353: f(x)= 55.28358467770072
# differential_evolution step 354: f(x)= 55.2800372942606
# differential_evolution step 355: f(x)= 55.2800372942606
# differential_evolution step 356: f(x)= 55.2800372942606
# differential_evolution step 357: f(x)= 55.2800372942606
# differential_evolution step 358: f(x)= 55.2800372942606
# differential_evolution step 359: f(x)= 55.2800372942606
# differential_evolution step 360: f(x)= 55.2800372942606
# differential_evolution step 361: f(x)= 55.2800372942606
# differential_evolution step 362: f(x)= 55.27179963594756
# differential_evolution step 363: f(x)= 55.27179963594756
# differential_evolution step 364: f(x)= 55.27179963594756
# differential_evolution step 365: f(x)= 55.27179963594756
# differential_evolution step 366: f(x)= 55.27179963594756
# differential_evolution step 367: f(x)= 55.27179963594756
# differential_evolution step 368: f(x)= 55.27179963594756
# differential_evolution step 369: f(x)= 55.271661464544955
# differential_evolution step 370: f(x)= 55.271661464544955
# differential_evolution step 371: f(x)= 55.271661464544955
# differential_evolution step 372: f(x)= 55.25048931584985
# differential_evolution step 373: f(x)= 55.25048931584985
# differential_evolution step 374: f(x)= 55.25048931584985
# differential_evolution step 375: f(x)= 55.24832535424672
# differential_evolution step 376: f(x)= 55.24832535424672
# differential_evolution step 377: f(x)= 55.24832535424672
# differential_evolution step 378: f(x)= 55.24832535424672
# differential_evolution step 379: f(x)= 55.24832535424672
# differential_evolution step 380: f(x)= 55.24832535424672
# differential_evolution step 381: f(x)= 55.24832535424672
# differential_evolution step 382: f(x)= 55.24832535424672
# differential_evolution step 383: f(x)= 55.24832535424672
# differential_evolution step 384: f(x)= 55.24832535424672
# differential_evolution step 385: f(x)= 55.24832535424672
# differential_evolution step 386: f(x)= 55.24832535424672
# differential_evolution step 387: f(x)= 55.24832535424672
# differential_evolution step 388: f(x)= 55.24832535424672
# differential_evolution step 389: f(x)= 55.24832535424672
# differential_evolution step 390: f(x)= 55.24763024169519
# differential_evolution step 391: f(x)= 55.24763024169519
# differential_evolution step 392: f(x)= 55.24763024169519
# differential_evolution step 393: f(x)= 55.24763024169519
# differential_evolution step 394: f(x)= 55.227190625932785
# differential_evolution step 395: f(x)= 55.22618861194499
# differential_evolution step 396: f(x)= 55.22618861194499
# differential_evolution step 397: f(x)= 55.20540847232017
# differential_evolution step 398: f(x)= 55.20540847232017
# differential_evolution step 399: f(x)= 55.20540847232017
# differential_evolution step 400: f(x)= 55.20540847232017
# differential_evolution step 401: f(x)= 55.20540847232017
# differential_evolution step 402: f(x)= 55.20540847232017
# differential_evolution step 403: f(x)= 55.20540847232017
# differential_evolution step 404: f(x)= 55.196537943770345
# differential_evolution step 405: f(x)= 55.177570475241886
# differential_evolution step 406: f(x)= 55.177570475241886
# differential_evolution step 407: f(x)= 55.177570475241886
# differential_evolution step 408: f(x)= 55.177570475241886
# differential_evolution step 409: f(x)= 55.177570475241886
# differential_evolution step 410: f(x)= 55.177570475241886
# differential_evolution step 411: f(x)= 55.177570475241886
# differential_evolution step 412: f(x)= 55.168110067872135
# differential_evolution step 413: f(x)= 55.168110067872135
# differential_evolution step 414: f(x)= 55.168110067872135
# differential_evolution step 415: f(x)= 55.168110067872135
# differential_evolution step 416: f(x)= 55.168110067872135
# differential_evolution step 417: f(x)= 55.168110067872135
# differential_evolution step 418: f(x)= 55.168110067872135
# differential_evolution step 419: f(x)= 55.168110067872135
# differential_evolution step 420: f(x)= 55.168110067872135
# differential_evolution step 421: f(x)= 55.168110067872135
# differential_evolution step 422: f(x)= 55.168110067872135
# differential_evolution step 423: f(x)= 55.168110067872135
# differential_evolution step 424: f(x)= 55.168110067872135
# differential_evolution step 425: f(x)= 55.168110067872135
# differential_evolution step 426: f(x)= 55.168110067872135
# differential_evolution step 427: f(x)= 55.168110067872135
# differential_evolution step 428: f(x)= 55.168110067872135
# differential_evolution step 429: f(x)= 55.168110067872135
# differential_evolution step 430: f(x)= 55.168110067872135
# differential_evolution step 431: f(x)= 55.168110067872135
# differential_evolution step 432: f(x)= 55.168110067872135
# differential_evolution step 433: f(x)= 55.168110067872135
# differential_evolution step 434: f(x)= 55.168110067872135
# differential_evolution step 435: f(x)= 55.168110067872135
# differential_evolution step 436: f(x)= 55.168110067872135
# differential_evolution step 437: f(x)= 55.168110067872135
# differential_evolution step 438: f(x)= 55.168110067872135
# differential_evolution step 439: f(x)= 55.168110067872135
# differential_evolution step 440: f(x)= 55.168110067872135
# differential_evolution step 441: f(x)= 55.168110067872135
# differential_evolution step 442: f(x)= 55.168110067872135
# differential_evolution step 443: f(x)= 55.168110067872135
# differential_evolution step 444: f(x)= 55.168110067872135
# differential_evolution step 445: f(x)= 55.15664828240206
# differential_evolution step 446: f(x)= 55.15664828240206
# differential_evolution step 447: f(x)= 55.15664828240206
# differential_evolution step 448: f(x)= 55.15664828240206
# differential_evolution step 449: f(x)= 55.15664828240206
# differential_evolution step 450: f(x)= 55.15664828240206
# differential_evolution step 451: f(x)= 55.156141314483605
# differential_evolution step 452: f(x)= 55.156141314483605
# differential_evolution step 453: f(x)= 55.156141314483605
# differential_evolution step 454: f(x)= 55.156141314483605
# differential_evolution step 455: f(x)= 55.156141314483605
# differential_evolution step 456: f(x)= 55.156141314483605
# differential_evolution step 457: f(x)= 55.156141314483605
# differential_evolution step 458: f(x)= 55.156141314483605
# differential_evolution step 459: f(x)= 55.156141314483605
# differential_evolution step 460: f(x)= 55.156141314483605
# differential_evolution step 461: f(x)= 55.15477818362639
# differential_evolution step 462: f(x)= 55.15128065614682
# differential_evolution step 463: f(x)= 55.15128065614682
# differential_evolution step 464: f(x)= 55.15128065614682
# differential_evolution step 465: f(x)= 55.147443477680106
# differential_evolution step 466: f(x)= 55.13986097433211
# differential_evolution step 467: f(x)= 55.13986097433211
# differential_evolution step 468: f(x)= 55.13986097433211
# differential_evolution step 469: f(x)= 55.13986097433211
# differential_evolution step 470: f(x)= 55.13986097433211
# differential_evolution step 471: f(x)= 55.13986097433211
# differential_evolution step 472: f(x)= 55.13986097433211
# differential_evolution step 473: f(x)= 55.13986097433211
# differential_evolution step 474: f(x)= 55.13986097433211
# differential_evolution step 475: f(x)= 55.13986097433211
# differential_evolution step 476: f(x)= 55.136850873472824
# differential_evolution step 477: f(x)= 55.136850873472824
# differential_evolution step 478: f(x)= 55.136850873472824
# differential_evolution step 479: f(x)= 55.136850873472824
# differential_evolution step 480: f(x)= 55.136850873472824
# differential_evolution step 481: f(x)= 55.136850873472824
# differential_evolution step 482: f(x)= 55.136850873472824
# differential_evolution step 483: f(x)= 55.136850873472824
# differential_evolution step 484: f(x)= 55.136850873472824
# differential_evolution step 485: f(x)= 55.136850873472824
# differential_evolution step 486: f(x)= 55.136850873472824
# differential_evolution step 487: f(x)= 55.136850873472824
# differential_evolution step 488: f(x)= 55.133048560803694
# differential_evolution step 489: f(x)= 55.133048560803694
# differential_evolution step 490: f(x)= 55.133048560803694
# differential_evolution step 491: f(x)= 55.133048560803694
# differential_evolution step 492: f(x)= 55.133048560803694
# differential_evolution step 493: f(x)= 55.133048560803694
# differential_evolution step 494: f(x)= 55.133048560803694
# differential_evolution step 495: f(x)= 55.133048560803694
# differential_evolution step 496: f(x)= 55.133048560803694
# differential_evolution step 497: f(x)= 55.133048560803694
# differential_evolution step 498: f(x)= 55.12934723908559
# differential_evolution step 499: f(x)= 55.12934723908559
# differential_evolution step 500: f(x)= 55.12934723908559
# differential_evolution step 501: f(x)= 55.12934723908559
# differential_evolution step 502: f(x)= 55.12934723908559
# differential_evolution step 503: f(x)= 55.12934723908559
# differential_evolution step 504: f(x)= 55.12934723908559
# differential_evolution step 505: f(x)= 55.12895689583685
# differential_evolution step 506: f(x)= 55.12895689583685
# differential_evolution step 507: f(x)= 55.128342296426524
# differential_evolution step 508: f(x)= 55.128342296426524
# differential_evolution step 509: f(x)= 55.128342296426524
# differential_evolution step 510: f(x)= 55.128105063426226
# differential_evolution step 511: f(x)= 55.12799094582569
# differential_evolution step 512: f(x)= 55.12799094582569
# differential_evolution step 513: f(x)= 55.126356630504716
# differential_evolution step 514: f(x)= 55.126356630504716
# differential_evolution step 515: f(x)= 55.126356630504716
# differential_evolution step 516: f(x)= 55.126356630504716
# differential_evolution step 517: f(x)= 55.126356630504716
# differential_evolution step 518: f(x)= 55.12503006621319
# differential_evolution step 519: f(x)= 55.12503006621319
# differential_evolution step 520: f(x)= 55.12503006621319
# differential_evolution step 521: f(x)= 55.12503006621319
# differential_evolution step 522: f(x)= 55.12503006621319
# differential_evolution step 523: f(x)= 55.12503006621319
# differential_evolution step 524: f(x)= 55.124962263554224
# differential_evolution step 525: f(x)= 55.12471095890086
# differential_evolution step 526: f(x)= 55.12471095890086
# differential_evolution step 527: f(x)= 55.12471095890086
# differential_evolution step 528: f(x)= 55.12471095890086
# differential_evolution step 529: f(x)= 55.12471095890086
# differential_evolution step 530: f(x)= 55.12445471120401
# differential_evolution step 531: f(x)= 55.12445471120401
# differential_evolution step 532: f(x)= 55.12403232737261
# differential_evolution step 533: f(x)= 55.12403232737261
# differential_evolution step 534: f(x)= 55.12403232737261
# differential_evolution step 535: f(x)= 55.12403232737261
# differential_evolution step 536: f(x)= 55.123699085093705
# differential_evolution step 537: f(x)= 55.12358969053087
# differential_evolution step 538: f(x)= 55.12302726050922
# differential_evolution step 539: f(x)= 55.12302726050922
# differential_evolution step 540: f(x)= 55.12302726050922
# differential_evolution step 541: f(x)= 55.12302726050922
# differential_evolution step 542: f(x)= 55.12302726050922
# differential_evolution step 543: f(x)= 55.12302726050922
# differential_evolution step 544: f(x)= 55.12302726050922
# differential_evolution step 545: f(x)= 55.12302726050922
# differential_evolution step 546: f(x)= 55.12302726050922
# differential_evolution step 547: f(x)= 55.12266701330496
# differential_evolution step 548: f(x)= 55.12266701330496
# differential_evolution step 549: f(x)= 55.12266701330496
# differential_evolution step 550: f(x)= 55.12266701330496
# differential_evolution step 551: f(x)= 55.12266701330496
# differential_evolution step 552: f(x)= 55.12245486384629
# differential_evolution step 553: f(x)= 55.12243679029836
# differential_evolution step 554: f(x)= 55.12243679029836
# differential_evolution step 555: f(x)= 55.12243679029836
# differential_evolution step 556: f(x)= 55.122298945870895
# differential_evolution step 557: f(x)= 55.12217383411023
# differential_evolution step 558: f(x)= 55.12217383411023
# differential_evolution step 559: f(x)= 55.12217383411023
# differential_evolution step 560: f(x)= 55.12217383411023
# differential_evolution step 561: f(x)= 55.12217383411023
# differential_evolution step 562: f(x)= 55.12217383411023
# differential_evolution step 563: f(x)= 55.12217383411023
# differential_evolution step 564: f(x)= 55.12217383411023
# differential_evolution step 565: f(x)= 55.1220817131633
# differential_evolution step 566: f(x)= 55.1220817131633
# differential_evolution step 567: f(x)= 55.12204269072755
# differential_evolution step 568: f(x)= 55.12204269072755
# differential_evolution step 569: f(x)= 55.12202918279761
# differential_evolution step 570: f(x)= 55.12202918279761
# differential_evolution step 571: f(x)= 55.12202918279761
# differential_evolution step 572: f(x)= 55.12202918279761
# differential_evolution step 573: f(x)= 55.121806965135534
# differential_evolution step 574: f(x)= 55.121806965135534
# differential_evolution step 575: f(x)= 55.121806965135534
# differential_evolution step 576: f(x)= 55.121806965135534
# differential_evolution step 577: f(x)= 55.12178249240871
# differential_evolution step 578: f(x)= 55.12178249240871
# differential_evolution step 579: f(x)= 55.12178249240871
# differential_evolution step 580: f(x)= 55.12178249240871
# differential_evolution step 581: f(x)= 55.12178249240871
# differential_evolution step 582: f(x)= 55.12177874211273
# differential_evolution step 583: f(x)= 55.12148461391485
# differential_evolution step 584: f(x)= 55.12148461391485
# differential_evolution step 585: f(x)= 55.12148461391485
# differential_evolution step 586: f(x)= 55.12148461391485
# differential_evolution step 587: f(x)= 55.12148461391485
# differential_evolution step 588: f(x)= 55.12148461391485
# differential_evolution step 589: f(x)= 55.12148461391485
# differential_evolution step 590: f(x)= 55.12148461391485
# differential_evolution step 591: f(x)= 55.12148461391485
# differential_evolution step 592: f(x)= 55.12148461391485
# differential_evolution step 593: f(x)= 55.12143020215673
# differential_evolution step 594: f(x)= 55.12143020215673
# differential_evolution step 595: f(x)= 55.12143020215673
# differential_evolution step 596: f(x)= 55.12134618395118
# differential_evolution step 597: f(x)= 55.121332999735415
# differential_evolution step 598: f(x)= 55.121266406990095
# differential_evolution step 599: f(x)= 55.121251726310405
# differential_evolution step 600: f(x)= 55.121251726310405
# differential_evolution step 601: f(x)= 55.121251726310405
# differential_evolution step 602: f(x)= 55.121251726310405
# differential_evolution step 603: f(x)= 55.121251726310405
# differential_evolution step 604: f(x)= 55.121251726310405
# differential_evolution step 605: f(x)= 55.12120772968805
# differential_evolution step 606: f(x)= 55.12120772968805
# differential_evolution step 607: f(x)= 55.12120772968805
# differential_evolution step 608: f(x)= 55.12120772968805
# differential_evolution step 609: f(x)= 55.12120772968805
# differential_evolution step 610: f(x)= 55.121205346980986
# differential_evolution step 611: f(x)= 55.121205346980986
# differential_evolution step 612: f(x)= 55.121205346980986
# differential_evolution step 613: f(x)= 55.121205346980986
# differential_evolution step 614: f(x)= 55.121204260010224
# differential_evolution step 615: f(x)= 55.121204260010224
# differential_evolution step 616: f(x)= 55.12119788404061
# differential_evolution step 617: f(x)= 55.12119788404061
# differential_evolution step 618: f(x)= 55.12119788404061
# differential_evolution step 619: f(x)= 55.121184464271145
# differential_evolution step 620: f(x)= 55.121184464271145
# differential_evolution step 621: f(x)= 55.121184464271145
# differential_evolution step 622: f(x)= 55.121184464271145
# differential_evolution step 623: f(x)= 55.121184464271145
# differential_evolution step 624: f(x)= 55.121172316767314
# differential_evolution step 625: f(x)= 55.12116516134318
# differential_evolution step 626: f(x)= 55.12116516134318
# differential_evolution step 627: f(x)= 55.12113175421167
# differential_evolution step 628: f(x)= 55.12113175421167
# differential_evolution step 629: f(x)= 55.12112553536524
# differential_evolution step 630: f(x)= 55.12112553536524
# differential_evolution step 631: f(x)= 55.12112553536524
# differential_evolution step 632: f(x)= 55.12112553536524
# differential_evolution step 633: f(x)= 55.12112553536524
# differential_evolution step 634: f(x)= 55.12112553536524
# differential_evolution step 635: f(x)= 55.12112553536524
# differential_evolution step 636: f(x)= 55.12112553536524
# differential_evolution step 637: f(x)= 55.12112553536524
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=2.5745, n=0.9338, x_0=34.4792
# Sérsic 2: I_e=1.0000, r_e=3.3418, n=0.1000, x_0=52.8144
# Sérsic 3: I_e=0.9011, r_e=3.0666, n=0.2184, x_0=49.6633
# Sérsic 4: I_e=1.0000, r_e=23.5769, n=0.8256, x_0=62.0000
# Sérsic 5: I_e=0.6066, r_e=22.5875, n=3.6310, x_0=64.4567
# Chi quadro minimo: 55.12107516795538
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HA)
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_HA, covariance_HA = curve_fit(model_convolved, x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0_HA[i] = params_curve_HA[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_HA)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_HA)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_HA)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_HA)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0_HA[i]:.4f}")

print(np.sqrt(np.diag(covariance_HA)))
#print(infodict.fvec**2)
chi2_HA = np.sum((((radial_profile_HA - model_convolved(x_axes, *params_curve_HA)) / radial_profile_error_HA)**2))
dof_HA = len(radial_profile_HA) - len(params_curve_HA)
chi2_reduced_HA = chi2_HA / dof_HA
print(chi2_reduced_HA)

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]],
       'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]]}#, 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("Halpha_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]], 
      ' Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]]}#, 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("Halpha_fit_error.csv", float_format='%.4f')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_7340\1149467859.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_7340\1149467859.py:21: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_7340\1149467859.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:511: RuntimeWarning: invalid value encountered in multiply
#   ret = ifft(sp1 * sp2, fshape, axes=axes)
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.1012, r_e=3.6130, n=0.8705, x_0=34.5412
# Sérsic 2: I_e=1.0211, r_e=5.7066, n=0.0546, x_0=54.3333
# Sérsic 3: I_e=1.6551, r_e=4.5275, n=0.2032, x_0=49.8096
# Sérsic 4: I_e=0.1634, r_e=40.5414, n=2.2671, x_0=66.1980
# Sérsic 5: I_e=0.6066, r_e=22.5875, n=3.6310, x_0=64.4567
# [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf inf inf inf inf]
# 352.56152060583463
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_7340\2291596625.py:1: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_curve_HA, covariance_HA = curve_fit(model_convolved, x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA)

# %%
params_curve_HA
# Out:
# array([1.10123019e+00, 3.61304816e+00, 8.70466139e-01, 3.45411822e+01,
#        1.02108308e+00, 5.70655852e+00, 5.45781538e-02, 5.43333444e+01,
#        1.65509735e+00, 4.52749387e+00, 2.03191935e-01, 4.98096267e+01,
#        1.63419574e-01, 4.05414484e+01, 2.26710817e+00, 6.61980494e+01,
#        6.06592007e-01, 2.25874755e+01, 3.63104725e+00, 6.44566869e+01,
#        4.28171551e-01, 1.91421910e+01, 6.57456692e+00, 8.30014883e+01])

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA)
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')

# %%
# Bounds:
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.5, x_0_HA[0]+1.5),   # x_0: circa la posizione di Halpha

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.5, x_0_HA[1]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.5, x_0_HA[2]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-1.5, x_0_HA[3]+1.5),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (x_0_HA[4]-1.5, x_0_HA[4]+1.5),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (x_0_HA[5]-1.5, x_0_HA[5]+1.5)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_conponent):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_HB)
plt.savefig('Radial_profile_Hbeta_kernel')

# %%
params_curve_HB, covariance_HB = curve_fit(model_convolved, x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_HB[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_HB)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_HB)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_HB)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_HB)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
      # ,       'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("Hbeta_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("Hbeta_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_HB)))
#print(infodict.fvec**2)
chi2_HB = np.sum((((radial_profile_HB - model_convolved(x_axes, *params_curve_HB)) / radial_profile_error_HB)**2))
dof_HB = len(radial_profile_HB) - len(params_curve_HB)
chi2_reduced_HB = chi2_HB / dof_HB
print(chi2_reduced_HB)

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB)
plt.savefig('Radial_profile_Hbeta_curve')

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')

# %%
# Bounds:
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.5, x_0_HA[0]+1.5),   # x_0: circa la posizione di Halpha

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.5, x_0_HA[1]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.5, x_0_HA[2]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-1.5, x_0_HA[3]+1.5),

 #   (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (x_0_HA[4]-1.5, x_0_HA[4]+1.5),

 #   (0, 1),
 #   (0, 50),
#    (0.1, 10),
 #   (x_0_HA[5]-1.5, x_0_HA[5]+1.5)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII)
plt.savefig('Radial_profile_NII_kernel')

# %%
params_curve_NII, covariance_NII = curve_fit(model_convolved, x_axes, radial_profile_NII, p0=result.x, sigma = radial_profile_error_NII)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_NII[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_NII)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_NII)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_NII)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_NII)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]} 
      # ,       'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("NII_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("NII_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_NII)))
#print(infodict.fvec**2)
chi2_NII = np.sum((((radial_profile_NII - model_convolved(x_axes, *params_curve_NII)) / radial_profile_error_NII)**2))
dof_NII = len(radial_profile_NII) - len(params_curve_NII)
chi2_reduced_NII = chi2_NII / dof_NII
print(chi2_reduced_NII)

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII)
plt.savefig('Radial_profile_NII_curve')

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')

# %%
# Bounds:
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.5, x_0_HA[0]+1.5),   # x_0: circa la posizione di Halpha

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.5, x_0_HA[1]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.5, x_0_HA[2]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-1.5, x_0_HA[3]+1.5),

#    (0, 1),
 #   (0, 50),
#    (0.1, 10),
#    (x_0_HA[4]-1.5, x_0_HA[4]+1.5),

#    (0, 1),
 #   (0, 50),
#    (0.1, 10),
#    (x_0_HA[5]-1.5, x_0_HA[5]+1.5)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_SII)
plt.savefig('Radial_profile_SII_diff')

# %%
params_curve_SII, covariance_SII = curve_fit(model_convolved, x_axes, radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_SII[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_SII)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_SII)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_SII)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_SII)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
       #,  'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("SII_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #,  'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("SII_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_SII)))
#print(infodict.fvec**2)
chi2_SII = np.sum((((radial_profile_SII - model_convolved(x_axes, *params_curve_SII)) / radial_profile_error_SII)**2))
dof_SII = len(radial_profile_SII) - len(params_curve_SII)
chi2_reduced_SII = chi2_SII / dof_SII
print(chi2_reduced_SII)

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII)
plt.savefig('Radial_profile_SII_curve')

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')

# %%
# Bounds:
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.5, x_0_HA[0]+1.5),   # x_0: circa la posizione di Halpha

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.5, x_0_HA[1]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.5, x_0_HA[2]+1.5),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-1.5, x_0_HA[3]+1.5),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (x_0_HA[4]-1.5, x_0_HA[4]+1.5),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (x_0_HA[5]-1.5, x_0_HA[5]+1.5)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII)
plt.savefig('Radial_profile_OIII_diff')

# %%
params_curve_OIII, covariance_OIII = curve_fit(model_convolved, x_axes, radial_profile_OIII, p0=result.x, sigma = radial_profile_error_OIII)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_OIII[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_OIII)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_OIII)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_OIII)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_OIII)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
       #, 'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("OIII_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("OIII_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_OIII)))
#print(infodict.fvec**2)
chi2_OIII = np.sum((((radial_profile_OIII - model_convolved(x_axes, *params_curve_OIII)) / radial_profile_error_OIII)**2))
dof_OIII = len(radial_profile_OIII) - len(params_curve_OIII)
chi2_reduced_OIII = chi2_OIII / dof_OIII
print(chi2_reduced_OIII)

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII)
plt.savefig('Radial_profile_OIII_curve')

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')

# %%
# Bounds:
bounds = [
       (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (45, 60),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80)

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (90, 100)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_continuum_1)
plt.savefig('Radial_profile_continuum_1_diff')

# %%
params_curve_continuum_1, covariance_continuum_1 = curve_fit(model_convolved, x_axes, radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_continuum_1[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_continuum_1)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_continuum_1)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_continuum_1)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_continuum_1)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
       #, 'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1.to_csv("Continuum_1_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("Continuum_1_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_continuum_1)))
#print(infodict.fvec**2)
chi2_continuum_1 = np.sum((((radial_profile_continuum_1 - model_convolved(x_axes, *params_curve_continuum_1)) / radial_profile_error_continuum_1)**2))
dof_continuum_1 = len(radial_profile_continuum_1) - len(params_curve_continuum_1)
chi2_reduced_continuum_1 = chi2_continuum_1 / dof_continuum_1
print(chi2_reduced_continuum_1)

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1)
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')

# %%
# Bounds:
bounds = [
        (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (45, 60),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),


#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (70, 80),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (90, 100)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_2)
plt.savefig('Radial_profile_continuum_2_diff')

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

# %%
params_curve_continuum_2, covariance_continuum_2 = curve_fit(model_convolved, x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2) #, bounds = bounds_list, maxfev=15000)
I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_continuum_2[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_continuum_2)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_continuum_2)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_continuum_2)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_continuum_2)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
       #, 'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1 = pd.DataFrame(data=d1, index =  ['I_e', 'r_e', 'n', 'x_0'])
df1.to_csv("Continuum_2_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
       #, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("Continuum_2_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_continuum_2)))
#print(infodict.fvec**2)
chi2_continuum_2 = np.sum((((radial_profile_continuum_2 - model_convolved(x_axes, *params_curve_continuum_2)) / radial_profile_error_continuum_2)**2))
dof_continuum_2 = len(radial_profile_continuum_2) - len(params_curve_continuum_2)
chi2_reduced_continuum_2 = chi2_continuum_2 / dof_continuum_2
print(chi2_reduced_continuum_2)

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2)
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = [
        (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (45, 60),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (70, 80),

#    (0, 1),
#    (0, 50),
#    (0.1, 10),
#    (90, 100)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_3)
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(model_convolved, x_axes, radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3)

I_e = np.zeros(n_component)
r_e = np.zeros(n_component)
n = np.zeros(n_component)
x_0_HA = np.zeros(n_component)

I_e_err = np.zeros(n_component)
r_e_err = np.zeros(n_component)
n_err = np.zeros(n_component)
x_0_err = np.zeros(n_component)

for i in range(n_component):
    I_e[i], r_e[i], n[i], x_0[i] = params_curve_continuum_3[i*4:(i+1)*4]
    I_e_err[i] = np.sqrt(np.diag(covariance_continuum_3)[i*4])
    r_e_err[i] = np.sqrt(np.diag(covariance_continuum_3)[(i*4)+1])
    n_err[i] = np.sqrt(np.diag(covariance_continuum_3)[(i*4)+2])
    x_0_err[i] = np.sqrt(np.diag(covariance_continuum_3)[(i*4)+3])
    print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

d1 = { 'Component 1': [I_e[0], r_e[0], n[0], x_0_HA[0]], 'Component 2': [I_e[1], r_e[1], n[1], x_0_HA[1]], 
       'Component 3': [I_e[2], r_e[2], n[2], x_0_HA[2]], 'Component 4': [I_e[3], r_e[3], n[3], x_0_HA[3]]}
#, 'Component 5': [I_e[4], r_e[4], n[4], x_0_HA[4]], 'Component 6': [I_e[5], r_e[5], n[5], x_0_HA[5]]}
df1.to_csv("Continuum_3_fit.csv", float_format='%.4f')

d2 = { 'Component 1': [I_e_err[0], r_e_err[0], n_err[0], x_0_err[0]], 'Component 2': [I_e_err[1], r_e_err[1], n_err[1], x_0_err[1]], 
       'Component 3': [I_e_err[2], r_e_err[2], n_err[2], x_0_err[2]], 'Component 4': [I_e_err[3], r_e_err[3], n_err[3], x_0_err[3]]}
#, 'Component 5': [I_e_err[4], r_e_err[4], n_err[4], x_0_err[4]], 'Component 6': [I_e_err[5], r_e_err[5], n_err[5], x_0_err[5]]}
df2 = pd.DataFrame(data=d2, index =  ['I_e error', 'r_e error', 'n error', 'x_0 error'])
df2.to_csv("Continuum_3_fit_error.csv", float_format='%.4f')

#print(covariance)
print(np.sqrt(np.diag(covariance_continuum_3)))
#print(infodict.fvec**2)
chi2_continuum_3 = np.sum((((radial_profile_continuum_3 - model_convolved(x_axes, *params_curve_continuum_3)) / radial_profile_error_continuum_3)**2))
dof_continuum_3 = len(radial_profile_continuum_3) - len(params_curve_continuum_3)
chi2_reduced_continuum_3 = chi2_continuum_3 / dof_continuum_3
print(chi2_reduced_continuum_3)

# %%
plot_diff(x_axes, params_curve_continuum_3, radial_profile_continuum_3)
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)
