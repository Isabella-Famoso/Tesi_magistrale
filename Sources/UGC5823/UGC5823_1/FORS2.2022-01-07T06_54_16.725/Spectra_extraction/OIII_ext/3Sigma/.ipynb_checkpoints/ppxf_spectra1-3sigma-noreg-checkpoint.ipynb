# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt") 
z = red[0][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.1848191  2.18554546 2.18627182 ... 3.48136987 3.48209623 3.48282259]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
# chi2/DOF: 0.02467; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
# chi2/DOF: 0.01590; DOF: 1914; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [1.46346363 1.26615401 0.97758734 ... 0.99059252 0.74794087 0.65019967]
# [1.16555315 1.17375587 1.1777357  ... 0.86045207 0.86090977 0.86179661]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-2.8520172 ,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -43        27
#  comp.  2:       -50        28
# chi2/DOF: 0.5612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.91      0.43     -43    27
# Comp:  1                Halpha      40.88      0.43     -43    27
# Comp:  2             [SII]6716      8.030      0.43     -50    28
# Comp:  2             [SII]6731      5.678      0.43     -50    28
# Comp:  2              HeII4687     0.3086      0.43     -50    28
# Comp:  2               HeI5876      1.136      0.43     -50    28
# Comp:  2          [OIII]5007_d      19.33      0.54     -50    28
# Comp:  2            [OI]6300_d      1.178      0.54     -50    28
# Comp:  2           [NII]6583_d      10.07      0.54     -50    28
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  36.47; gas flux:     14 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  104.2; gas flux:     56 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   19.3; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  14.61; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.7792; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.902; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  37.89; gas flux:     20 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.309; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   18.9; gas flux:     14 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        23         4
#  comp.  1:       -41        37
#  comp.  2:       -48        11
# chi2/DOF: 0.5456; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 76; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.26      0.44     -41    37
# Comp:  1                Halpha      42.84      0.44     -41    37
# Comp:  2             [SII]6716      7.812      0.41     -48    11
# Comp:  2             [SII]6731      5.720      0.41     -48    11
# Comp:  2              HeII4687     0.2691      0.41     -48    11
# Comp:  2               HeI5876      1.001      0.41     -48    11
# Comp:  2          [OIII]5007_d      18.66      0.52     -48    11
# Comp:  2            [OI]6300_d     0.6762      0.52     -48    11
# Comp:  2           [NII]6583_d      9.600      0.52     -48    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -41        29
#  comp.  2:       -51        24
# chi2/DOF: 0.5524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.61      0.43     -41    29
# Comp:  1                Halpha      40.96      0.43     -41    29
# Comp:  2             [SII]6716      8.156      0.42     -51    24
# Comp:  2             [SII]6731      5.733      0.42     -51    24
# Comp:  2              HeII4687     0.1909      0.42     -51    24
# Comp:  2               HeI5876      1.371      0.42     -51    24
# Comp:  2          [OIII]5007_d      19.18      0.53     -51    24
# Comp:  2            [OI]6300_d      1.367      0.53     -51    24
# Comp:  2           [NII]6583_d      9.898      0.53     -51    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        36
#  comp.  1:       -43        24
#  comp.  2:       -46        34
# chi2/DOF: 0.5506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.77      0.42     -43    24
# Comp:  1                Halpha      40.85      0.42     -43    24
# Comp:  2             [SII]6716      7.592      0.43     -46    34
# Comp:  2             [SII]6731      6.166      0.43     -46    34
# Comp:  2              HeII4687     0.2988      0.43     -46    34
# Comp:  2               HeI5876      1.046      0.43     -46    34
# Comp:  2          [OIII]5007_d      18.92      0.55     -46    34
# Comp:  2            [OI]6300_d      1.394      0.55     -46    34
# Comp:  2           [NII]6583_d      10.03      0.55     -46    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6         1
#  comp.  1:       -42        24
#  comp.  2:       -51        19
# chi2/DOF: 0.5526; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.82      0.42     -42    24
# Comp:  1                Halpha      40.52      0.42     -42    24
# Comp:  2             [SII]6716      8.055      0.42     -51    19
# Comp:  2             [SII]6731      5.450      0.42     -51    19
# Comp:  2              HeII4687     0.3209      0.42     -51    19
# Comp:  2               HeI5876      1.214      0.42     -51    19
# Comp:  2          [OIII]5007_d      18.04      0.53     -51    19
# Comp:  2            [OI]6300_d      1.059      0.53     -51    19
# Comp:  2           [NII]6583_d      9.663      0.53     -51    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        41
#  comp.  1:       -45        20
#  comp.  2:       -50        27
# chi2/DOF: 0.5450; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.37      0.42     -45    20
# Comp:  1                Halpha      39.85      0.42     -45    20
# Comp:  2             [SII]6716      8.334      0.42     -50    27
# Comp:  2             [SII]6731      5.507      0.42     -50    27
# Comp:  2              HeII4687     0.3708      0.42     -50    27
# Comp:  2               HeI5876     0.9347      0.42     -50    27
# Comp:  2          [OIII]5007_d      19.91      0.54     -50    27
# Comp:  2            [OI]6300_d      1.484      0.54     -50    27
# Comp:  2           [NII]6583_d      9.858      0.54     -50    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6        61
#  comp.  1:       -43        20
#  comp.  2:       -46        36
# chi2/DOF: 0.5490; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.06      0.42     -43    20
# Comp:  1                Halpha      40.31      0.42     -43    20
# Comp:  2             [SII]6716      8.052      0.44     -46    36
# Comp:  2             [SII]6731      6.014      0.44     -46    36
# Comp:  2              HeII4687     0.2598      0.44     -46    36
# Comp:  2               HeI5876      1.356      0.44     -46    36
# Comp:  2          [OIII]5007_d      19.14      0.55     -46    36
# Comp:  2            [OI]6300_d      1.569      0.55     -46    36
# Comp:  2           [NII]6583_d      10.94      0.55     -46    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -39        33
#  comp.  2:       -55        27
# chi2/DOF: 0.5470; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.04      0.43     -39    33
# Comp:  1                Halpha      42.14      0.43     -39    33
# Comp:  2             [SII]6716      7.868      0.42     -55    27
# Comp:  2             [SII]6731      5.789      0.42     -55    27
# Comp:  2              HeII4687     0.2547      0.42     -55    27
# Comp:  2               HeI5876      1.029      0.42     -55    27
# Comp:  2          [OIII]5007_d      18.95      0.54     -55    27
# Comp:  2            [OI]6300_d      1.267      0.54     -55    27
# Comp:  2           [NII]6583_d      9.468      0.54     -55    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        52
#  comp.  1:       -45        20
#  comp.  2:       -47        41
# chi2/DOF: 0.5425; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.16      0.42     -45    20
# Comp:  1                Halpha      39.70      0.42     -45    20
# Comp:  2             [SII]6716      8.515      0.44     -47    41
# Comp:  2             [SII]6731      5.905      0.44     -47    41
# Comp:  2              HeII4687     0.4766      0.44     -47    41
# Comp:  2               HeI5876      1.331      0.44     -47    41
# Comp:  2          [OIII]5007_d      19.73      0.56     -47    41
# Comp:  2            [OI]6300_d      1.452      0.56     -47    41
# Comp:  2           [NII]6583_d      10.73      0.56     -47    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        17
#  comp.  1:       -42        22
#  comp.  2:       -47        29
# chi2/DOF: 0.5547; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.62      0.42     -42    22
# Comp:  1                Halpha      40.37      0.42     -42    22
# Comp:  2             [SII]6716      8.443      0.43     -47    29
# Comp:  2             [SII]6731      5.519      0.43     -47    29
# Comp:  2              HeII4687     0.3542      0.43     -47    29
# Comp:  2               HeI5876      1.141      0.43     -47    29
# Comp:  2          [OIII]5007_d      19.21      0.54     -47    29
# Comp:  2            [OI]6300_d      1.359      0.54     -47    29
# Comp:  2           [NII]6583_d      10.31      0.54     -47    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:       -39        35
#  comp.  2:       -51        25
# chi2/DOF: 0.5421; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.72      0.43     -39    35
# Comp:  1                Halpha      42.50      0.43     -39    35
# Comp:  2             [SII]6716      8.010      0.42     -51    25
# Comp:  2             [SII]6731      5.635      0.42     -51    25
# Comp:  2              HeII4687     0.1175      0.42     -51    25
# Comp:  2               HeI5876      1.361      0.42     -51    25
# Comp:  2          [OIII]5007_d      19.12      0.53     -51    25
# Comp:  2            [OI]6300_d      1.177      0.53     -51    25
# Comp:  2           [NII]6583_d      9.431      0.53     -51    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        14
#  comp.  1:       -46        16
#  comp.  2:       -50        18
# chi2/DOF: 0.5420; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.98      0.41     -46    16
# Comp:  1                Halpha      39.84      0.41     -46    16
# Comp:  2             [SII]6716      8.077      0.42     -50    18
# Comp:  2             [SII]6731      5.672      0.42     -50    18
# Comp:  2              HeII4687     0.3126      0.42     -50    18
# Comp:  2               HeI5876      1.313      0.42     -50    18
# Comp:  2          [OIII]5007_d      18.16      0.53     -50    18
# Comp:  2            [OI]6300_d      1.511      0.53     -50    18
# Comp:  2           [NII]6583_d      10.45      0.53     -50    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -41        38
#  comp.  2:       -53        28
# chi2/DOF: 0.5380; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.26      0.44     -41    38
# Comp:  1                Halpha      43.12      0.44     -41    38
# Comp:  2             [SII]6716      7.874      0.43     -53    28
# Comp:  2             [SII]6731      5.719      0.43     -53    28
# Comp:  2              HeII4687     0.3533      0.43     -53    28
# Comp:  2               HeI5876      1.563      0.43     -53    28
# Comp:  2          [OIII]5007_d      18.38      0.54     -53    28
# Comp:  2            [OI]6300_d      1.023      0.54     -53    28
# Comp:  2           [NII]6583_d      9.746      0.54     -53    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -43        26
#  comp.  2:       -53        28
# chi2/DOF: 0.5572; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.19      0.42     -43    26
# Comp:  1                Halpha      40.99      0.42     -43    26
# Comp:  2             [SII]6716      8.341      0.43     -53    28
# Comp:  2             [SII]6731      5.943      0.43     -53    28
# Comp:  2              HeII4687     0.2524      0.43     -53    28
# Comp:  2               HeI5876      1.216      0.43     -53    28
# Comp:  2          [OIII]5007_d      19.15      0.54     -53    28
# Comp:  2            [OI]6300_d     0.8475      0.54     -53    28
# Comp:  2           [NII]6583_d      9.708      0.54     -53    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        36
#  comp.  1:       -40        35
#  comp.  2:       -49        33
# chi2/DOF: 0.5504; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.34      0.43     -40    35
# Comp:  1                Halpha      42.34      0.43     -40    35
# Comp:  2             [SII]6716      8.462      0.43     -49    33
# Comp:  2             [SII]6731      5.529      0.43     -49    33
# Comp:  2              HeII4687     0.2452      0.43     -49    33
# Comp:  2               HeI5876      1.391      0.43     -49    33
# Comp:  2          [OIII]5007_d      19.71      0.55     -49    33
# Comp:  2            [OI]6300_d      1.184      0.55     -49    33
# Comp:  2           [NII]6583_d      10.08      0.55     -49    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        36
#  comp.  1:       -44        13
#  comp.  2:       -52        25
# chi2/DOF: 0.5429; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.21      0.41     -44    13
# Comp:  1                Halpha      39.31      0.41     -44    13
# Comp:  2             [SII]6716      8.174      0.42     -52    25
# Comp:  2             [SII]6731      5.548      0.42     -52    25
# Comp:  2              HeII4687     0.2029      0.42     -52    25
# Comp:  2               HeI5876      1.213      0.42     -52    25
# Comp:  2          [OIII]5007_d      19.63      0.53     -52    25
# Comp:  2            [OI]6300_d      1.336      0.53     -52    25
# Comp:  2           [NII]6583_d      10.18      0.53     -52    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15        38
#  comp.  1:       -41        23
#  comp.  2:       -48        37
# chi2/DOF: 0.5526; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.36      0.42     -41    23
# Comp:  1                Halpha      40.69      0.42     -41    23
# Comp:  2             [SII]6716      7.934      0.44     -48    37
# Comp:  2             [SII]6731      5.767      0.44     -48    37
# Comp:  2              HeII4687     0.2613      0.44     -48    37
# Comp:  2               HeI5876      1.334      0.44     -48    37
# Comp:  2          [OIII]5007_d      20.91      0.55     -48    37
# Comp:  2            [OI]6300_d      1.256      0.55     -48    37
# Comp:  2           [NII]6583_d      10.52      0.55     -48    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        57
#  comp.  1:       -46        21
#  comp.  2:       -51        14
# chi2/DOF: 0.5448; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.89      0.42     -46    21
# Comp:  1                Halpha      39.66      0.42     -46    21
# Comp:  2             [SII]6716      8.268      0.41     -51    14
# Comp:  2             [SII]6731      5.382      0.41     -51    14
# Comp:  2              HeII4687     0.3276      0.41     -51    14
# Comp:  2               HeI5876      1.197      0.41     -51    14
# Comp:  2          [OIII]5007_d      17.98      0.52     -51    14
# Comp:  2            [OI]6300_d      1.224      0.52     -51    14
# Comp:  2           [NII]6583_d      9.872      0.52     -51    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -42        32
#  comp.  2:       -48        34
# chi2/DOF: 0.5532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.73      0.43     -42    32
# Comp:  1                Halpha      41.21      0.43     -42    32
# Comp:  2             [SII]6716      8.212      0.43     -48    34
# Comp:  2             [SII]6731      5.670      0.43     -48    34
# Comp:  2              HeII4687     0.3078      0.43     -48    34
# Comp:  2               HeI5876      1.425      0.43     -48    34
# Comp:  2          [OIII]5007_d      20.65      0.55     -48    34
# Comp:  2            [OI]6300_d      1.000      0.55     -48    34
# Comp:  2           [NII]6583_d      10.13      0.55     -48    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:       -44        19
#  comp.  2:       -47        17
# chi2/DOF: 0.5500; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.47      0.42     -44    19
# Comp:  1                Halpha      39.89      0.42     -44    19
# Comp:  2             [SII]6716      8.386      0.42     -47    17
# Comp:  2             [SII]6731      5.496      0.42     -47    17
# Comp:  2              HeII4687     0.3016      0.42     -47    17
# Comp:  2               HeI5876     0.9987      0.42     -47    17
# Comp:  2          [OIII]5007_d      19.20      0.52     -47    17
# Comp:  2            [OI]6300_d      1.510      0.52     -47    17
# Comp:  2           [NII]6583_d      9.999      0.52     -47    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -44        21
#  comp.  2:       -52        39
# chi2/DOF: 0.5512; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.15      0.42     -44    21
# Comp:  1                Halpha      39.81      0.42     -44    21
# Comp:  2             [SII]6716      7.664      0.44     -52    39
# Comp:  2             [SII]6731      5.765      0.44     -52    39
# Comp:  2              HeII4687     0.2437      0.44     -52    39
# Comp:  2               HeI5876     0.7576      0.44     -52    39
# Comp:  2          [OIII]5007_d      19.63      0.56     -52    39
# Comp:  2            [OI]6300_d      1.326      0.56     -52    39
# Comp:  2           [NII]6583_d      10.50      0.56     -52    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:       -43        25
#  comp.  2:       -49        30
# chi2/DOF: 0.5508; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.41      0.42     -43    25
# Comp:  1                Halpha      40.79      0.42     -43    25
# Comp:  2             [SII]6716      8.101      0.43     -49    30
# Comp:  2             [SII]6731      6.025      0.43     -49    30
# Comp:  2              HeII4687     0.4140      0.43     -49    30
# Comp:  2               HeI5876      1.343      0.43     -49    30
# Comp:  2          [OIII]5007_d      19.92      0.54     -49    30
# Comp:  2            [OI]6300_d      1.514      0.54     -49    30
# Comp:  2           [NII]6583_d      10.27      0.54     -49    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11        19
#  comp.  1:       -45        22
#  comp.  2:       -52        26
# chi2/DOF: 0.5506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.06      0.42     -45    22
# Comp:  1                Halpha      39.47      0.42     -45    22
# Comp:  2             [SII]6716      8.104      0.42     -52    26
# Comp:  2             [SII]6731      5.490      0.42     -52    26
# Comp:  2              HeII4687     0.3301      0.42     -52    26
# Comp:  2               HeI5876      1.252      0.42     -52    26
# Comp:  2          [OIII]5007_d      19.36      0.54     -52    26
# Comp:  2            [OI]6300_d      1.232      0.54     -52    26
# Comp:  2           [NII]6583_d      9.668      0.54     -52    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:       -40        34
#  comp.  2:       -47        36
# chi2/DOF: 0.5467; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.41      0.43     -40    34
# Comp:  1                Halpha      42.38      0.43     -40    34
# Comp:  2             [SII]6716      8.201      0.44     -47    36
# Comp:  2             [SII]6731      5.924      0.44     -47    36
# Comp:  2              HeII4687     0.2854      0.44     -47    36
# Comp:  2               HeI5876     0.8969      0.44     -47    36
# Comp:  2          [OIII]5007_d      20.36      0.55     -47    36
# Comp:  2            [OI]6300_d     0.9483      0.55     -47    36
# Comp:  2           [NII]6583_d      10.53      0.55     -47    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        38
#  comp.  1:       -43        26
#  comp.  2:       -52        27
# chi2/DOF: 0.5540; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.24      0.42     -43    26
# Comp:  1                Halpha      41.08      0.42     -43    26
# Comp:  2             [SII]6716      8.420      0.42     -52    27
# Comp:  2             [SII]6731      5.437      0.42     -52    27
# Comp:  2              HeII4687     0.4033      0.42     -52    27
# Comp:  2               HeI5876      1.219      0.42     -52    27
# Comp:  2          [OIII]5007_d      19.93      0.54     -52    27
# Comp:  2            [OI]6300_d      1.396      0.54     -52    27
# Comp:  2           [NII]6583_d      9.906      0.54     -52    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        76
#  comp.  1:       -40        35
#  comp.  2:       -48        44
# chi2/DOF: 0.5382; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.61      0.43     -40    35
# Comp:  1                Halpha      42.04      0.43     -40    35
# Comp:  2             [SII]6716      9.111      0.45     -48    44
# Comp:  2             [SII]6731      5.643      0.45     -48    44
# Comp:  2              HeII4687     0.3804      0.45     -48    44
# Comp:  2               HeI5876      1.156      0.45     -48    44
# Comp:  2          [OIII]5007_d      21.18      0.57     -48    44
# Comp:  2            [OI]6300_d      1.014      0.57     -48    44
# Comp:  2           [NII]6583_d      11.03      0.57     -48    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        64
#  comp.  1:       -44        10
#  comp.  2:       -48        37
# chi2/DOF: 0.5388; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.49      0.41     -44    10
# Comp:  1                Halpha      39.02      0.41     -44    10
# Comp:  2             [SII]6716      7.691      0.44     -48    37
# Comp:  2             [SII]6731      5.564      0.44     -48    37
# Comp:  2              HeII4687     0.3516      0.44     -48    37
# Comp:  2               HeI5876      1.362      0.44     -48    37
# Comp:  2          [OIII]5007_d      21.04      0.55     -48    37
# Comp:  2            [OI]6300_d      1.213      0.55     -48    37
# Comp:  2           [NII]6583_d      10.45      0.55     -48    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:       -47        22
#  comp.  2:       -53        32
# chi2/DOF: 0.5481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.42      0.42     -47    22
# Comp:  1                Halpha      40.26      0.42     -47    22
# Comp:  2             [SII]6716      8.112      0.43     -53    32
# Comp:  2             [SII]6731      5.748      0.43     -53    32
# Comp:  2              HeII4687     0.3398      0.43     -53    32
# Comp:  2               HeI5876      1.277      0.43     -53    32
# Comp:  2          [OIII]5007_d      19.77      0.54     -53    32
# Comp:  2            [OI]6300_d      1.180      0.54     -53    32
# Comp:  2           [NII]6583_d      10.14      0.54     -53    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -43        24
#  comp.  2:       -51        27
# chi2/DOF: 0.5573; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.86      0.42     -43    24
# Comp:  1                Halpha      40.65      0.42     -43    24
# Comp:  2             [SII]6716      8.116      0.42     -51    27
# Comp:  2             [SII]6731      5.862      0.42     -51    27
# Comp:  2              HeII4687     0.2230      0.42     -51    27
# Comp:  2               HeI5876     0.9472      0.42     -51    27
# Comp:  2          [OIII]5007_d      18.71      0.54     -51    27
# Comp:  2            [OI]6300_d      1.356      0.54     -51    27
# Comp:  2           [NII]6583_d      9.924      0.54     -51    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         1
#  comp.  1:       -42        26
#  comp.  2:       -46        33
# chi2/DOF: 0.5543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.28      0.42     -42    26
# Comp:  1                Halpha      41.10      0.42     -42    26
# Comp:  2             [SII]6716      7.979      0.43     -46    33
# Comp:  2             [SII]6731      5.659      0.43     -46    33
# Comp:  2              HeII4687     0.2252      0.43     -46    33
# Comp:  2               HeI5876      1.128      0.43     -46    33
# Comp:  2          [OIII]5007_d      19.05      0.55     -46    33
# Comp:  2            [OI]6300_d      1.258      0.55     -46    33
# Comp:  2           [NII]6583_d      10.50      0.55     -46    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -44        13
#  comp.  2:       -51        11
# chi2/DOF: 0.5425; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.87      0.41     -44    13
# Comp:  1                Halpha      39.29      0.41     -44    13
# Comp:  2             [SII]6716      7.596      0.41     -51    11
# Comp:  2             [SII]6731      5.381      0.41     -51    11
# Comp:  2              HeII4687     0.2887      0.41     -51    11
# Comp:  2               HeI5876      1.265      0.41     -51    11
# Comp:  2          [OIII]5007_d      19.06      0.52     -51    11
# Comp:  2            [OI]6300_d     0.8323      0.52     -51    11
# Comp:  2           [NII]6583_d      9.539      0.52     -51    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        29
#  comp.  1:       -40        35
#  comp.  2:       -50        36
# chi2/DOF: 0.5502; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.23      0.43     -40    35
# Comp:  1                Halpha      42.23      0.43     -40    35
# Comp:  2             [SII]6716      8.111      0.44     -50    36
# Comp:  2             [SII]6731      6.152      0.44     -50    36
# Comp:  2              HeII4687     0.2410      0.44     -50    36
# Comp:  2               HeI5876      1.053      0.44     -50    36
# Comp:  2          [OIII]5007_d      19.75      0.55     -50    36
# Comp:  2            [OI]6300_d      1.116      0.55     -50    36
# Comp:  2           [NII]6583_d      10.44      0.55     -50    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41       109
#  comp.  1:       -42        22
#  comp.  2:       -43        30
# chi2/DOF: 0.5471; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.33      0.42     -42    22
# Comp:  1                Halpha      40.26      0.42     -42    22
# Comp:  2             [SII]6716      8.201      0.43     -43    30
# Comp:  2             [SII]6731      5.712      0.43     -43    30
# Comp:  2              HeII4687     0.3352      0.43     -43    30
# Comp:  2               HeI5876     0.9772      0.43     -43    30
# Comp:  2          [OIII]5007_d      20.32      0.54     -43    30
# Comp:  2            [OI]6300_d     0.9291      0.54     -43    30
# Comp:  2           [NII]6583_d      10.16      0.54     -43    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         1
#  comp.  1:       -41        20
#  comp.  2:       -45        31
# chi2/DOF: 0.5504; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.76      0.42     -41    20
# Comp:  1                Halpha      40.16      0.42     -41    20
# Comp:  2             [SII]6716      8.337      0.43     -45    31
# Comp:  2             [SII]6731      5.562      0.43     -45    31
# Comp:  2              HeII4687     0.3135      0.43     -45    31
# Comp:  2               HeI5876     0.9420      0.43     -45    31
# Comp:  2          [OIII]5007_d      20.61      0.54     -45    31
# Comp:  2            [OI]6300_d      1.203      0.54     -45    31
# Comp:  2           [NII]6583_d      9.777      0.54     -45    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -44        15
#  comp.  2:       -45        28
# chi2/DOF: 0.5452; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.78      0.41     -44    15
# Comp:  1                Halpha      39.22      0.41     -44    15
# Comp:  2             [SII]6716      8.643      0.43     -45    28
# Comp:  2             [SII]6731      5.652      0.43     -45    28
# Comp:  2              HeII4687     0.3196      0.43     -45    28
# Comp:  2               HeI5876      1.358      0.43     -45    28
# Comp:  2          [OIII]5007_d      19.48      0.54     -45    28
# Comp:  2            [OI]6300_d     0.8613      0.54     -45    28
# Comp:  2           [NII]6583_d      9.338      0.54     -45    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:       -45        19
#  comp.  2:       -52        26
# chi2/DOF: 0.5506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.54      0.42     -45    19
# Comp:  1                Halpha      39.28      0.42     -45    19
# Comp:  2             [SII]6716      7.816      0.42     -52    26
# Comp:  2             [SII]6731      5.388      0.42     -52    26
# Comp:  2              HeII4687     0.4783      0.42     -52    26
# Comp:  2               HeI5876      1.410      0.42     -52    26
# Comp:  2          [OIII]5007_d      19.17      0.53     -52    26
# Comp:  2            [OI]6300_d      1.103      0.53     -52    26
# Comp:  2           [NII]6583_d      9.467      0.53     -52    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:       -42        33
#  comp.  2:       -48        24
# chi2/DOF: 0.5519; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.61      0.43     -42    33
# Comp:  1                Halpha      41.13      0.43     -42    33
# Comp:  2             [SII]6716      8.485      0.42     -48    24
# Comp:  2             [SII]6731      5.704      0.42     -48    24
# Comp:  2              HeII4687     0.2769      0.42     -48    24
# Comp:  2               HeI5876      1.215      0.42     -48    24
# Comp:  2          [OIII]5007_d      19.42      0.53     -48    24
# Comp:  2            [OI]6300_d      1.488      0.53     -48    24
# Comp:  2           [NII]6583_d      10.33      0.53     -48    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        40
#  comp.  1:       -44        31
#  comp.  2:       -46        23
# chi2/DOF: 0.5527; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.67      0.43     -44    31
# Comp:  1                Halpha      41.60      0.43     -44    31
# Comp:  2             [SII]6716      7.502      0.42     -46    23
# Comp:  2             [SII]6731      5.475      0.42     -46    23
# Comp:  2              HeII4687     0.2973      0.42     -46    23
# Comp:  2               HeI5876     0.7228      0.42     -46    23
# Comp:  2          [OIII]5007_d      19.73      0.53     -46    23
# Comp:  2            [OI]6300_d      1.100      0.53     -46    23
# Comp:  2           [NII]6583_d      10.28      0.53     -46    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -44        13
#  comp.  2:       -49        36
# chi2/DOF: 0.5439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.97      0.41     -44    13
# Comp:  1                Halpha      39.21      0.41     -44    13
# Comp:  2             [SII]6716      8.260      0.44     -49    36
# Comp:  2             [SII]6731      5.794      0.44     -49    36
# Comp:  2              HeII4687     0.3573      0.44     -49    36
# Comp:  2               HeI5876     0.9447      0.44     -49    36
# Comp:  2          [OIII]5007_d      20.69      0.55     -49    36
# Comp:  2            [OI]6300_d      1.494      0.55     -49    36
# Comp:  2           [NII]6583_d      9.787      0.55     -49    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -44        13
#  comp.  2:       -47        26
# chi2/DOF: 0.5482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.73      0.41     -44    13
# Comp:  1                Halpha      39.31      0.41     -44    13
# Comp:  2             [SII]6716      8.049      0.42     -47    26
# Comp:  2             [SII]6731      5.732      0.42     -47    26
# Comp:  2              HeII4687     0.2407      0.42     -47    26
# Comp:  2               HeI5876      1.163      0.42     -47    26
# Comp:  2          [OIII]5007_d      19.46      0.53     -47    26
# Comp:  2            [OI]6300_d     0.7602      0.53     -47    26
# Comp:  2           [NII]6583_d      10.02      0.53     -47    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -42        31
#  comp.  2:       -50        39
# chi2/DOF: 0.5480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.71      0.43     -42    31
# Comp:  1                Halpha      41.06      0.43     -42    31
# Comp:  2             [SII]6716      8.183      0.44     -50    39
# Comp:  2             [SII]6731      5.669      0.44     -50    39
# Comp:  2              HeII4687     0.3216      0.44     -50    39
# Comp:  2               HeI5876      1.210      0.44     -50    39
# Comp:  2          [OIII]5007_d      20.77      0.56     -50    39
# Comp:  2            [OI]6300_d     0.9920      0.56     -50    39
# Comp:  2           [NII]6583_d      10.35      0.56     -50    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -40        36
#  comp.  2:       -45        30
# chi2/DOF: 0.5458; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.88      0.44     -40    36
# Comp:  1                Halpha      42.71      0.44     -40    36
# Comp:  2             [SII]6716      8.213      0.43     -45    30
# Comp:  2             [SII]6731      5.702      0.43     -45    30
# Comp:  2              HeII4687     0.2755      0.43     -45    30
# Comp:  2               HeI5876      1.285      0.43     -45    30
# Comp:  2          [OIII]5007_d      18.68      0.54     -45    30
# Comp:  2            [OI]6300_d      1.017      0.54     -45    30
# Comp:  2           [NII]6583_d      10.03      0.54     -45    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11        34
#  comp.  1:       -45        29
#  comp.  2:       -48        38
# chi2/DOF: 0.5494; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.98      0.43     -45    29
# Comp:  1                Halpha      41.58      0.43     -45    29
# Comp:  2             [SII]6716      7.670      0.44     -48    38
# Comp:  2             [SII]6731      5.969      0.44     -48    38
# ...
# chi2/DOF: 0.5576; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.11      0.43     -42    29
# Comp:  1                Halpha      41.05      0.43     -42    29
# Comp:  2             [SII]6716      8.104      0.43     -49    29
# Comp:  2             [SII]6731      5.728      0.43     -49    29
# Comp:  2              HeII4687     0.3178      0.43     -49    29
# Comp:  2               HeI5876      1.323      0.43     -49    29
# Comp:  2          [OIII]5007_d      19.46      0.54     -49    29
# Comp:  2            [OI]6300_d     0.9567      0.54     -49    29
# Comp:  2           [NII]6583_d      10.53      0.54     -49    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        25
#  comp.  1:       -44        15
#  comp.  2:       -49        16
# chi2/DOF: 0.5445; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.35      0.41     -44    15
# Comp:  1                Halpha      39.44      0.41     -44    15
# Comp:  2             [SII]6716      7.174      0.41     -49    16
# Comp:  2             [SII]6731      5.628      0.41     -49    16
# Comp:  2              HeII4687     0.2090      0.41     -49    16
# Comp:  2               HeI5876      1.205      0.41     -49    16
# Comp:  2          [OIII]5007_d      19.07      0.52     -49    16
# Comp:  2            [OI]6300_d      1.089      0.52     -49    16
# Comp:  2           [NII]6583_d      9.831      0.52     -49    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:       -46        26
#  comp.  2:       -43        34
# chi2/DOF: 0.5446; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.47      0.42     -46    26
# Comp:  1                Halpha      40.31      0.42     -46    26
# Comp:  2             [SII]6716      8.557      0.43     -43    34
# Comp:  2             [SII]6731      5.757      0.43     -43    34
# Comp:  2              HeII4687     0.2946      0.43     -43    34
# Comp:  2               HeI5876     0.9436      0.43     -43    34
# Comp:  2          [OIII]5007_d      20.70      0.55     -43    34
# Comp:  2            [OI]6300_d     0.6445      0.55     -43    34
# Comp:  2           [NII]6583_d      10.16      0.55     -43    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -41        30
#  comp.  2:       -52        16
# chi2/DOF: 0.5502; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.25      0.43     -41    30
# Comp:  1                Halpha      40.70      0.43     -41    30
# Comp:  2             [SII]6716      7.659      0.41     -52    16
# Comp:  2             [SII]6731      5.204      0.41     -52    16
# Comp:  2              HeII4687     0.4126      0.41     -52    16
# Comp:  2               HeI5876      1.171      0.41     -52    16
# Comp:  2          [OIII]5007_d      17.70      0.52     -52    16
# Comp:  2            [OI]6300_d      1.302      0.52     -52    16
# Comp:  2           [NII]6583_d      9.437      0.52     -52    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        13
#  comp.  1:       -42        29
#  comp.  2:       -50        40
# chi2/DOF: 0.5507; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.59      0.43     -42    29
# Comp:  1                Halpha      41.12      0.43     -42    29
# Comp:  2             [SII]6716      8.178      0.44     -50    40
# Comp:  2             [SII]6731      6.142      0.44     -50    40
# Comp:  2              HeII4687     0.2368      0.44     -50    40
# Comp:  2               HeI5876      1.107      0.44     -50    40
# Comp:  2          [OIII]5007_d      19.49      0.56     -50    40
# Comp:  2            [OI]6300_d     0.8862      0.56     -50    40
# Comp:  2           [NII]6583_d      10.74      0.56     -50    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6        41
#  comp.  1:       -45        22
#  comp.  2:       -56        30
# chi2/DOF: 0.5448; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.69      0.42     -45    22
# Comp:  1                Halpha      40.00      0.42     -45    22
# Comp:  2             [SII]6716      8.032      0.43     -56    30
# Comp:  2             [SII]6731      5.282      0.43     -56    30
# Comp:  2              HeII4687     0.3675      0.43     -56    30
# Comp:  2               HeI5876     0.9030      0.43     -56    30
# Comp:  2          [OIII]5007_d      18.74      0.54     -56    30
# Comp:  2            [OI]6300_d      1.531      0.54     -56    30
# Comp:  2           [NII]6583_d      9.794      0.54     -56    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:       -45        20
#  comp.  2:       -47        30
# chi2/DOF: 0.5491; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.87      0.42     -45    20
# Comp:  1                Halpha      39.62      0.42     -45    20
# Comp:  2             [SII]6716      8.354      0.43     -47    30
# Comp:  2             [SII]6731      5.656      0.43     -47    30
# Comp:  2              HeII4687     0.3144      0.43     -47    30
# Comp:  2               HeI5876      1.223      0.43     -47    30
# Comp:  2          [OIII]5007_d      19.07      0.54     -47    30
# Comp:  2            [OI]6300_d      1.102      0.54     -47    30
# Comp:  2           [NII]6583_d      10.35      0.54     -47    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        75
#  comp.  1:       -41        36
#  comp.  2:       -49        36
# chi2/DOF: 0.5452; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.06      0.44     -41    36
# Comp:  1                Halpha      42.64      0.44     -41    36
# Comp:  2             [SII]6716      8.259      0.44     -49    36
# Comp:  2             [SII]6731      5.644      0.44     -49    36
# Comp:  2              HeII4687     0.2845      0.44     -49    36
# Comp:  2               HeI5876     0.8679      0.44     -49    36
# Comp:  2          [OIII]5007_d      20.73      0.55     -49    36
# Comp:  2            [OI]6300_d      1.135      0.55     -49    36
# Comp:  2           [NII]6583_d      10.49      0.55     -49    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        34
#  comp.  1:       -45        18
#  comp.  2:       -53        10
# chi2/DOF: 0.5455; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.93      0.42     -45    18
# Comp:  1                Halpha      39.58      0.42     -45    18
# Comp:  2             [SII]6716      7.898      0.41     -53    10
# Comp:  2             [SII]6731      5.491      0.41     -53    10
# Comp:  2              HeII4687     0.3157      0.41     -53    10
# Comp:  2               HeI5876     0.9136      0.41     -53    10
# Comp:  2          [OIII]5007_d      18.16      0.52     -53    10
# Comp:  2            [OI]6300_d      1.147      0.52     -53    10
# Comp:  2           [NII]6583_d      9.941      0.52     -53    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         5
#  comp.  1:       -42        19
#  comp.  2:       -50        25
# chi2/DOF: 0.5506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.14      0.42     -42    19
# Comp:  1                Halpha      40.04      0.42     -42    19
# Comp:  2             [SII]6716      8.246      0.42     -50    25
# Comp:  2             [SII]6731      5.830      0.42     -50    25
# Comp:  2              HeII4687     0.4046      0.42     -50    25
# Comp:  2               HeI5876     0.8094      0.42     -50    25
# Comp:  2          [OIII]5007_d      18.07      0.53     -50    25
# Comp:  2            [OI]6300_d      1.154      0.53     -50    25
# Comp:  2           [NII]6583_d      9.814      0.53     -50    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24         1
#  comp.  1:       -40        34
#  comp.  2:       -53        30
# chi2/DOF: 0.5458; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.90      0.43     -40    34
# Comp:  1                Halpha      42.39      0.43     -40    34
# Comp:  2             [SII]6716      8.757      0.43     -53    30
# Comp:  2             [SII]6731      5.342      0.43     -53    30
# Comp:  2              HeII4687     0.2277      0.43     -53    30
# Comp:  2               HeI5876     0.9708      0.43     -53    30
# Comp:  2          [OIII]5007_d      18.50      0.54     -53    30
# Comp:  2            [OI]6300_d      1.078      0.54     -53    30
# Comp:  2           [NII]6583_d      9.639      0.54     -53    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        66
#  comp.  1:       -45        23
#  comp.  2:       -51        11
# chi2/DOF: 0.5480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.17      0.42     -45    23
# Comp:  1                Halpha      40.06      0.42     -45    23
# Comp:  2             [SII]6716      7.562      0.41     -51    11
# Comp:  2             [SII]6731      5.570      0.41     -51    11
# Comp:  2              HeII4687     0.3069      0.41     -51    11
# Comp:  2               HeI5876      1.081      0.41     -51    11
# Comp:  2          [OIII]5007_d      17.45      0.52     -51    11
# Comp:  2            [OI]6300_d      1.050      0.52     -51    11
# Comp:  2           [NII]6583_d      9.492      0.52     -51    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -45        21
#  comp.  2:       -53        21
# chi2/DOF: 0.5473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.44      0.42     -45    21
# Comp:  1                Halpha      39.88      0.42     -45    21
# Comp:  2             [SII]6716      8.013      0.42     -53    21
# Comp:  2             [SII]6731      5.309      0.42     -53    21
# Comp:  2              HeII4687     0.3846      0.42     -53    21
# Comp:  2               HeI5876      1.132      0.42     -53    21
# Comp:  2          [OIII]5007_d      19.68      0.53     -53    21
# Comp:  2            [OI]6300_d      1.528      0.53     -53    21
# Comp:  2           [NII]6583_d      10.01      0.53     -53    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
#  comp.  1:       -44        16
#  comp.  2:       -48        33
# chi2/DOF: 0.5489; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.22      0.41     -44    16
# Comp:  1                Halpha      39.19      0.41     -44    16
# Comp:  2             [SII]6716      8.364      0.43     -48    33
# Comp:  2             [SII]6731      6.207      0.43     -48    33
# Comp:  2              HeII4687     0.3746      0.43     -48    33
# Comp:  2               HeI5876     0.8418      0.43     -48    33
# Comp:  2          [OIII]5007_d      19.48      0.55     -48    33
# Comp:  2            [OI]6300_d      1.156      0.55     -48    33
# Comp:  2           [NII]6583_d      9.774      0.55     -48    33
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_1_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
