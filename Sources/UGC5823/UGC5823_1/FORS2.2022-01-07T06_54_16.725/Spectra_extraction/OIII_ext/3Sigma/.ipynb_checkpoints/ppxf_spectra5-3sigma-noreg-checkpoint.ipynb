# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt")
z = red[4][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4370.02424683 4371.47709313 4372.92993943 ... 6963.35489697 6964.80774328
#  6966.26058958] [0.15953075 0.14550268 0.1681445  ... 0.11268221 0.12903517 0.12436222] [0.0101869 0.0101869 0.0101869 ... 0.0101869 0.0101869 0.0101869]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18501212 2.18573855 2.18646497 ... 3.48167745 3.48240387 3.48313029]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        29
# chi2/DOF: 0.003381; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        29
# chi2/DOF: 0.002268; DOF: 1913; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-12.70966752,  28.72102181])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        50
#  comp.  1:       -26        24
#  comp.  2:       -29        16
# chi2/DOF: 0.6134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.215      0.15     -26    24
# Comp:  1                Halpha      7.522      0.15     -26    24
# Comp:  2             [SII]6716      2.380      0.14     -29    16
# Comp:  2             [SII]6731      1.832      0.14     -29    16
# Comp:  2              HeII4687    0.07880      0.14     -29    16
# Comp:  2               HeI5876     0.3766      0.14     -29    16
# Comp:  2          [OIII]5007_d      2.307      0.18     -29    16
# Comp:  2            [OI]6300_d     0.4977      0.18     -29    16
# Comp:  2           [NII]6583_d      3.655      0.18     -29    16
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  15.42; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  49.91; gas flux:     10 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  16.48; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  13.01; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  0.574; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.767; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  12.89; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.718; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  18.67; gas flux:      5 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        65
#  comp.  1:       -26        32
#  comp.  2:       -30        19
# chi2/DOF: 0.6096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.320      0.15     -26    32
# Comp:  1                Halpha      7.773      0.15     -26    32
# Comp:  2             [SII]6716      2.390      0.15     -30    19
# Comp:  2             [SII]6731      1.840      0.15     -30    19
# Comp:  2              HeII4687   0.003249      0.15     -30    19
# Comp:  2               HeI5876     0.3778      0.15     -30    19
# Comp:  2          [OIII]5007_d      2.326      0.18     -30    19
# Comp:  2            [OI]6300_d     0.4437      0.18     -30    19
# Comp:  2           [NII]6583_d      3.646      0.18     -30    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        43
#  comp.  1:       -24        26
#  comp.  2:       -30        12
# chi2/DOF: 0.6075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.248      0.15     -24    26
# Comp:  1                Halpha      7.523      0.15     -24    26
# Comp:  2             [SII]6716      2.390      0.14     -30    12
# Comp:  2             [SII]6731      1.711      0.14     -30    12
# Comp:  2              HeII4687     0.2701      0.14     -30    12
# Comp:  2               HeI5876     0.4345      0.14     -30    12
# Comp:  2          [OIII]5007_d      2.349      0.18     -30    12
# Comp:  2            [OI]6300_d     0.5431      0.18     -30    12
# Comp:  2           [NII]6583_d      3.614      0.18     -30    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        43
#  comp.  1:       -25        22
#  comp.  2:       -28        15
# chi2/DOF: 0.6070; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.565      0.15     -25    22
# Comp:  1                Halpha      7.660      0.15     -25    22
# Comp:  2             [SII]6716      2.341      0.14     -28    15
# Comp:  2             [SII]6731      1.822      0.14     -28    15
# Comp:  2              HeII4687      0.000      0.14     -28    15
# Comp:  2               HeI5876     0.3693      0.14     -28    15
# Comp:  2          [OIII]5007_d      2.169      0.18     -28    15
# Comp:  2            [OI]6300_d     0.4735      0.18     -28    15
# Comp:  2           [NII]6583_d      3.632      0.18     -28    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        17
#  comp.  1:       -26        19
#  comp.  2:       -29        14
# chi2/DOF: 0.6035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.190      0.15     -26    19
# Comp:  1                Halpha      7.427      0.15     -26    19
# Comp:  2             [SII]6716      2.436      0.14     -29    14
# Comp:  2             [SII]6731      1.946      0.14     -29    14
# Comp:  2              HeII4687     0.1845      0.14     -29    14
# Comp:  2               HeI5876     0.4532      0.14     -29    14
# Comp:  2          [OIII]5007_d      2.268      0.18     -29    14
# Comp:  2            [OI]6300_d     0.4426      0.18     -29    14
# Comp:  2           [NII]6583_d      3.573      0.18     -29    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        57
#  comp.  1:       -27        22
#  comp.  2:       -29        16
# chi2/DOF: 0.6084; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.359      0.15     -27    22
# Comp:  1                Halpha      7.416      0.15     -27    22
# Comp:  2             [SII]6716      2.381      0.14     -29    16
# Comp:  2             [SII]6731      1.832      0.14     -29    16
# Comp:  2              HeII4687    0.08978      0.14     -29    16
# Comp:  2               HeI5876     0.3613      0.14     -29    16
# Comp:  2          [OIII]5007_d      2.373      0.18     -29    16
# Comp:  2            [OI]6300_d     0.4964      0.18     -29    16
# Comp:  2           [NII]6583_d      3.730      0.18     -29    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        69
#  comp.  1:       -26        19
#  comp.  2:       -29        23
# chi2/DOF: 0.6074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.243      0.15     -26    19
# Comp:  1                Halpha      7.540      0.15     -26    19
# Comp:  2             [SII]6716      2.391      0.15     -29    23
# Comp:  2             [SII]6731      1.751      0.15     -29    23
# Comp:  2              HeII4687    0.08967      0.15     -29    23
# Comp:  2               HeI5876     0.4078      0.15     -29    23
# Comp:  2          [OIII]5007_d      2.244      0.19     -29    23
# Comp:  2            [OI]6300_d     0.5321      0.19     -29    23
# Comp:  2           [NII]6583_d      3.818      0.19     -29    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        51
#  comp.  1:       -24        27
#  comp.  2:       -31        10
# chi2/DOF: 0.6074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.435      0.15     -24    27
# Comp:  1                Halpha      7.705      0.15     -24    27
# Comp:  2             [SII]6716      2.358      0.14     -31    10
# Comp:  2             [SII]6731      1.882      0.14     -31    10
# Comp:  2              HeII4687     0.1927      0.14     -31    10
# Comp:  2               HeI5876     0.3559      0.14     -31    10
# Comp:  2          [OIII]5007_d      2.332      0.18     -31    10
# Comp:  2            [OI]6300_d     0.5006      0.18     -31    10
# Comp:  2           [NII]6583_d      3.562      0.18     -31    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        50
#  comp.  1:       -26        23
#  comp.  2:       -28        23
# chi2/DOF: 0.6058; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.462      0.15     -26    23
# Comp:  1                Halpha      7.457      0.15     -26    23
# Comp:  2             [SII]6716      2.408      0.15     -28    23
# Comp:  2             [SII]6731      1.931      0.15     -28    23
# Comp:  2              HeII4687      0.000      0.15     -28    23
# Comp:  2               HeI5876     0.4146      0.15     -28    23
# Comp:  2          [OIII]5007_d      2.281      0.19     -28    23
# Comp:  2            [OI]6300_d     0.5733      0.19     -28    23
# Comp:  2           [NII]6583_d      3.740      0.19     -28    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        36
#  comp.  1:       -25        19
#  comp.  2:       -27        20
# chi2/DOF: 0.6063; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.164      0.15     -25    19
# Comp:  1                Halpha      7.495      0.15     -25    19
# Comp:  2             [SII]6716      2.417      0.15     -27    20
# Comp:  2             [SII]6731      1.849      0.15     -27    20
# Comp:  2              HeII4687      0.000      0.15     -27    20
# Comp:  2               HeI5876     0.4100      0.15     -27    20
# Comp:  2          [OIII]5007_d      2.285      0.18     -27    20
# Comp:  2            [OI]6300_d     0.5657      0.18     -27    20
# Comp:  2           [NII]6583_d      3.797      0.18     -27    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        49
#  comp.  1:       -24        30
#  comp.  2:       -29        12
# chi2/DOF: 0.6081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.182      0.15     -24    30
# Comp:  1                Halpha      7.633      0.15     -24    30
# Comp:  2             [SII]6716      2.373      0.14     -29    12
# Comp:  2             [SII]6731      1.922      0.14     -29    12
# Comp:  2              HeII4687     0.1948      0.14     -29    12
# Comp:  2               HeI5876     0.4125      0.14     -29    12
# Comp:  2          [OIII]5007_d      2.278      0.18     -29    12
# Comp:  2            [OI]6300_d     0.5148      0.18     -29    12
# Comp:  2           [NII]6583_d      3.602      0.18     -29    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        63
#  comp.  1:       -27        20
#  comp.  2:       -28        13
# chi2/DOF: 0.6080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.273      0.15     -27    20
# Comp:  1                Halpha      7.453      0.15     -27    20
# Comp:  2             [SII]6716      2.412      0.14     -28    13
# Comp:  2             [SII]6731      1.815      0.14     -28    13
# Comp:  2              HeII4687      0.000      0.14     -28    13
# Comp:  2               HeI5876     0.3899      0.14     -28    13
# Comp:  2          [OIII]5007_d      2.270      0.18     -28    13
# Comp:  2            [OI]6300_d     0.5161      0.18     -28    13
# Comp:  2           [NII]6583_d      3.706      0.18     -28    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        61
#  comp.  1:       -26        32
#  comp.  2:       -31         6
# chi2/DOF: 0.6073; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.205      0.15     -26    32
# Comp:  1                Halpha      7.724      0.15     -26    32
# Comp:  2             [SII]6716      2.326      0.14     -31     6
# Comp:  2             [SII]6731      1.790      0.14     -31     6
# Comp:  2              HeII4687     0.1705      0.14     -31     6
# Comp:  2               HeI5876     0.4002      0.14     -31     6
# Comp:  2          [OIII]5007_d      2.138      0.18     -31     6
# Comp:  2            [OI]6300_d     0.5135      0.18     -31     6
# Comp:  2           [NII]6583_d      3.562      0.18     -31     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        34
#  comp.  1:       -26        24
#  comp.  2:       -30        22
# chi2/DOF: 0.6083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.397      0.15     -26    24
# Comp:  1                Halpha      7.505      0.15     -26    24
# Comp:  2             [SII]6716      2.418      0.15     -30    22
# Comp:  2             [SII]6731      1.881      0.15     -30    22
# Comp:  2              HeII4687      0.000      0.15     -30    22
# Comp:  2               HeI5876     0.4188      0.15     -30    22
# Comp:  2          [OIII]5007_d      2.334      0.19     -30    22
# Comp:  2            [OI]6300_d     0.4140      0.19     -30    22
# Comp:  2           [NII]6583_d      3.764      0.19     -30    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        35
#  comp.  1:       -25        27
#  comp.  2:       -28        21
# chi2/DOF: 0.6078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.089      0.15     -25    27
# Comp:  1                Halpha      7.506      0.15     -25    27
# Comp:  2             [SII]6716      2.420      0.15     -28    21
# Comp:  2             [SII]6731      1.874      0.15     -28    21
# Comp:  2              HeII4687     0.1037      0.15     -28    21
# Comp:  2               HeI5876     0.4151      0.15     -28    21
# Comp:  2          [OIII]5007_d      2.320      0.18     -28    21
# Comp:  2            [OI]6300_d     0.4839      0.18     -28    21
# Comp:  2           [NII]6583_d      3.687      0.18     -28    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        39
#  comp.  1:       -26        14
#  comp.  2:       -29        11
# chi2/DOF: 0.6018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.030      0.14     -26    14
# Comp:  1                Halpha      7.383      0.14     -26    14
# Comp:  2             [SII]6716      2.404      0.14     -29    11
# Comp:  2             [SII]6731      1.733      0.14     -29    11
# Comp:  2              HeII4687     0.2151      0.14     -29    11
# Comp:  2               HeI5876     0.3874      0.14     -29    11
# Comp:  2          [OIII]5007_d      2.255      0.18     -29    11
# Comp:  2            [OI]6300_d     0.5410      0.18     -29    11
# Comp:  2           [NII]6583_d      3.551      0.18     -29    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        42
#  comp.  1:       -25        22
#  comp.  2:       -28        18
# chi2/DOF: 0.6094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.255      0.15     -25    22
# Comp:  1                Halpha      7.574      0.15     -25    22
# Comp:  2             [SII]6716      2.341      0.15     -28    18
# Comp:  2             [SII]6731      1.717      0.15     -28    18
# Comp:  2              HeII4687      0.000      0.15     -28    18
# Comp:  2               HeI5876     0.4235      0.15     -28    18
# Comp:  2          [OIII]5007_d      2.397      0.18     -28    18
# Comp:  2            [OI]6300_d     0.4821      0.18     -28    18
# Comp:  2           [NII]6583_d      3.716      0.18     -28    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        61
#  comp.  1:       -27        23
#  comp.  2:       -30        16
# chi2/DOF: 0.6051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.417      0.15     -27    23
# Comp:  1                Halpha      7.665      0.15     -27    23
# Comp:  2             [SII]6716      2.401      0.14     -30    16
# Comp:  2             [SII]6731      1.930      0.14     -30    16
# Comp:  2              HeII4687      0.000      0.14     -30    16
# Comp:  2               HeI5876     0.4226      0.14     -30    16
# Comp:  2          [OIII]5007_d      2.228      0.18     -30    16
# Comp:  2            [OI]6300_d     0.5435      0.18     -30    16
# Comp:  2           [NII]6583_d      3.749      0.18     -30    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        53
#  comp.  1:       -25        27
#  comp.  2:       -28        23
# chi2/DOF: 0.6029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.065      0.15     -25    27
# Comp:  1                Halpha      7.612      0.15     -25    27
# Comp:  2             [SII]6716      2.435      0.15     -28    23
# Comp:  2             [SII]6731      1.756      0.15     -28    23
# Comp:  2              HeII4687     0.3079      0.15     -28    23
# Comp:  2               HeI5876     0.4369      0.15     -28    23
# Comp:  2          [OIII]5007_d      2.395      0.19     -28    23
# Comp:  2            [OI]6300_d     0.4453      0.19     -28    23
# Comp:  2           [NII]6583_d      3.694      0.19     -28    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        63
#  comp.  1:       -26        23
#  comp.  2:       -28         1
# chi2/DOF: 0.6079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.090      0.15     -26    23
# Comp:  1                Halpha      7.484      0.15     -26    23
# Comp:  2             [SII]6716      2.356      0.14     -28     1
# Comp:  2             [SII]6731      1.794      0.14     -28     1
# Comp:  2              HeII4687     0.1925      0.14     -28     1
# Comp:  2               HeI5876     0.3391      0.14     -28     1
# Comp:  2          [OIII]5007_d      2.304      0.18     -28     1
# Comp:  2            [OI]6300_d     0.5228      0.18     -28     1
# Comp:  2           [NII]6583_d      3.524      0.18     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        38
#  comp.  1:       -26        22
#  comp.  2:       -31        24
# chi2/DOF: 0.6053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.108      0.15     -26    22
# Comp:  1                Halpha      7.440      0.15     -26    22
# Comp:  2             [SII]6716      2.390      0.15     -31    24
# Comp:  2             [SII]6731      1.969      0.15     -31    24
# Comp:  2              HeII4687     0.3124      0.15     -31    24
# Comp:  2               HeI5876     0.3699      0.15     -31    24
# Comp:  2          [OIII]5007_d      2.347      0.19     -31    24
# Comp:  2            [OI]6300_d     0.5026      0.19     -31    24
# Comp:  2           [NII]6583_d      3.814      0.19     -31    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        33
#  comp.  1:       -26        23
#  comp.  2:       -32        24
# chi2/DOF: 0.6075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.469      0.15     -26    23
# Comp:  1                Halpha      7.494      0.15     -26    23
# Comp:  2             [SII]6716      2.424      0.15     -32    24
# Comp:  2             [SII]6731      1.854      0.15     -32    24
# Comp:  2              HeII4687      0.000      0.15     -32    24
# Comp:  2               HeI5876     0.4174      0.15     -32    24
# Comp:  2          [OIII]5007_d      2.479      0.19     -32    24
# Comp:  2            [OI]6300_d     0.5444      0.19     -32    24
# Comp:  2           [NII]6583_d      3.703      0.19     -32    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        51
#  comp.  1:       -26        22
#  comp.  2:       -29        15
# chi2/DOF: 0.6093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.374      0.15     -26    22
# Comp:  1                Halpha      7.470      0.15     -26    22
# Comp:  2             [SII]6716      2.378      0.14     -29    15
# Comp:  2             [SII]6731      1.923      0.14     -29    15
# Comp:  2              HeII4687     0.1630      0.14     -29    15
# Comp:  2               HeI5876     0.3962      0.14     -29    15
# Comp:  2          [OIII]5007_d      2.322      0.18     -29    15
# Comp:  2            [OI]6300_d     0.5063      0.18     -29    15
# Comp:  2           [NII]6583_d      3.688      0.18     -29    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        51
#  comp.  1:       -25        29
#  comp.  2:       -30        25
# chi2/DOF: 0.6070; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.453      0.15     -25    29
# Comp:  1                Halpha      7.678      0.15     -25    29
# Comp:  2             [SII]6716      2.430      0.15     -30    25
# Comp:  2             [SII]6731      1.874      0.15     -30    25
# Comp:  2              HeII4687     0.2814      0.15     -30    25
# Comp:  2               HeI5876     0.3669      0.15     -30    25
# Comp:  2          [OIII]5007_d      2.305      0.19     -30    25
# Comp:  2            [OI]6300_d     0.4408      0.19     -30    25
# Comp:  2           [NII]6583_d      3.794      0.19     -30    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        54
#  comp.  1:       -26        21
#  comp.  2:       -30         7
# chi2/DOF: 0.6067; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.285      0.15     -26    21
# Comp:  1                Halpha      7.531      0.15     -26    21
# Comp:  2             [SII]6716      2.346      0.14     -30     7
# Comp:  2             [SII]6731      1.897      0.14     -30     7
# Comp:  2              HeII4687   0.006863      0.14     -30     7
# Comp:  2               HeI5876     0.3979      0.14     -30     7
# Comp:  2          [OIII]5007_d      2.360      0.18     -30     7
# Comp:  2            [OI]6300_d     0.4743      0.18     -30     7
# Comp:  2           [NII]6583_d      3.555      0.18     -30     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        56
#  comp.  1:       -24        30
#  comp.  2:       -28        27
# chi2/DOF: 0.6048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.503      0.15     -24    30
# Comp:  1                Halpha      7.792      0.15     -24    30
# Comp:  2             [SII]6716      2.482      0.15     -28    27
# Comp:  2             [SII]6731      1.904      0.15     -28    27
# Comp:  2              HeII4687      0.000      0.15     -28    27
# Comp:  2               HeI5876     0.3719      0.15     -28    27
# Comp:  2          [OIII]5007_d      2.394      0.19     -28    27
# Comp:  2            [OI]6300_d     0.5232      0.19     -28    27
# Comp:  2           [NII]6583_d      3.873      0.19     -28    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        41
#  comp.  1:       -26        19
#  comp.  2:       -29        14
# chi2/DOF: 0.6057; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.486      0.15     -26    19
# Comp:  1                Halpha      7.475      0.15     -26    19
# Comp:  2             [SII]6716      2.356      0.14     -29    14
# Comp:  2             [SII]6731      1.939      0.14     -29    14
# Comp:  2              HeII4687     0.1142      0.14     -29    14
# Comp:  2               HeI5876     0.4108      0.14     -29    14
# Comp:  2          [OIII]5007_d      2.437      0.18     -29    14
# Comp:  2            [OI]6300_d     0.4436      0.18     -29    14
# Comp:  2           [NII]6583_d      3.664      0.18     -29    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        49
#  comp.  1:       -27        23
#  comp.  2:       -30        19
# chi2/DOF: 0.6033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.419      0.15     -27    23
# Comp:  1                Halpha      7.591      0.15     -27    23
# Comp:  2             [SII]6716      2.412      0.15     -30    19
# Comp:  2             [SII]6731      1.743      0.15     -30    19
# Comp:  2              HeII4687     0.1201      0.15     -30    19
# Comp:  2               HeI5876     0.4116      0.15     -30    19
# Comp:  2          [OIII]5007_d      2.413      0.18     -30    19
# Comp:  2            [OI]6300_d     0.4937      0.18     -30    19
# Comp:  2           [NII]6583_d      3.647      0.18     -30    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        43
#  comp.  1:       -26        21
#  comp.  2:       -32        20
# chi2/DOF: 0.6075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.299      0.15     -26    21
# Comp:  1                Halpha      7.556      0.15     -26    21
# Comp:  2             [SII]6716      2.403      0.15     -32    20
# Comp:  2             [SII]6731      1.842      0.15     -32    20
# Comp:  2              HeII4687     0.2910      0.15     -32    20
# Comp:  2               HeI5876     0.3629      0.15     -32    20
# Comp:  2          [OIII]5007_d      2.306      0.18     -32    20
# Comp:  2            [OI]6300_d     0.5555      0.18     -32    20
# Comp:  2           [NII]6583_d      3.678      0.18     -32    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        56
#  comp.  1:       -26        27
#  comp.  2:       -27        21
# chi2/DOF: 0.6077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.362      0.15     -26    27
# Comp:  1                Halpha      7.774      0.15     -26    27
# Comp:  2             [SII]6716      2.387      0.15     -27    21
# Comp:  2             [SII]6731      1.859      0.15     -27    21
# Comp:  2              HeII4687     0.1844      0.15     -27    21
# Comp:  2               HeI5876     0.3820      0.15     -27    21
# Comp:  2          [OIII]5007_d      2.249      0.18     -27    21
# Comp:  2            [OI]6300_d     0.5172      0.18     -27    21
# Comp:  2           [NII]6583_d      3.720      0.18     -27    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        59
#  comp.  1:       -25        17
#  comp.  2:       -31        17
# chi2/DOF: 0.6065; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.193      0.15     -25    17
# Comp:  1                Halpha      7.327      0.15     -25    17
# Comp:  2             [SII]6716      2.358      0.15     -31    17
# Comp:  2             [SII]6731      1.949      0.15     -31    17
# Comp:  2              HeII4687   0.007296      0.15     -31    17
# Comp:  2               HeI5876     0.4370      0.15     -31    17
# Comp:  2          [OIII]5007_d      2.326      0.18     -31    17
# Comp:  2            [OI]6300_d     0.4404      0.18     -31    17
# Comp:  2           [NII]6583_d      3.653      0.18     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        36
#  comp.  1:       -24        28
#  comp.  2:       -31        27
# chi2/DOF: 0.6077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.318      0.15     -24    28
# Comp:  1                Halpha      7.639      0.15     -24    28
# Comp:  2             [SII]6716      2.415      0.15     -31    27
# Comp:  2             [SII]6731      1.883      0.15     -31    27
# Comp:  2              HeII4687     0.2792      0.15     -31    27
# Comp:  2               HeI5876     0.3835      0.15     -31    27
# Comp:  2          [OIII]5007_d      2.377      0.19     -31    27
# Comp:  2            [OI]6300_d     0.4820      0.19     -31    27
# Comp:  2           [NII]6583_d      3.783      0.19     -31    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        57
#  comp.  1:       -25        21
#  comp.  2:       -28        18
# chi2/DOF: 0.6049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.167      0.15     -25    21
# Comp:  1                Halpha      7.511      0.15     -25    21
# Comp:  2             [SII]6716      2.339      0.15     -28    18
# Comp:  2             [SII]6731      1.905      0.15     -28    18
# Comp:  2              HeII4687     0.3551      0.15     -28    18
# Comp:  2               HeI5876     0.3644      0.15     -28    18
# Comp:  2          [OIII]5007_d      2.364      0.18     -28    18
# Comp:  2            [OI]6300_d     0.5415      0.18     -28    18
# Comp:  2           [NII]6583_d      3.645      0.18     -28    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        42
#  comp.  1:       -25        21
#  comp.  2:       -29        15
# chi2/DOF: 0.6066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.393      0.15     -25    21
# Comp:  1                Halpha      7.460      0.15     -25    21
# Comp:  2             [SII]6716      2.379      0.14     -29    15
# Comp:  2             [SII]6731      1.730      0.14     -29    15
# Comp:  2              HeII4687     0.1637      0.14     -29    15
# Comp:  2               HeI5876     0.3562      0.14     -29    15
# Comp:  2          [OIII]5007_d      2.458      0.18     -29    15
# Comp:  2            [OI]6300_d     0.4602      0.18     -29    15
# Comp:  2           [NII]6583_d      3.661      0.18     -29    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        37
#  comp.  1:       -25        17
#  comp.  2:       -30        14
# chi2/DOF: 0.6063; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.070      0.15     -25    17
# Comp:  1                Halpha      7.427      0.15     -25    17
# Comp:  2             [SII]6716      2.382      0.14     -30    14
# Comp:  2             [SII]6731      1.807      0.14     -30    14
# Comp:  2              HeII4687     0.1848      0.14     -30    14
# Comp:  2               HeI5876     0.4298      0.14     -30    14
# Comp:  2          [OIII]5007_d      2.299      0.18     -30    14
# Comp:  2            [OI]6300_d     0.4902      0.18     -30    14
# Comp:  2           [NII]6583_d      3.586      0.18     -30    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        54
#  comp.  1:       -26        20
#  comp.  2:       -29         1
# chi2/DOF: 0.6101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.214      0.15     -26    20
# Comp:  1                Halpha      7.472      0.15     -26    20
# Comp:  2             [SII]6716      2.315      0.14     -29     1
# Comp:  2             [SII]6731      1.791      0.14     -29     1
# Comp:  2              HeII4687      0.000      0.14     -29     1
# Comp:  2               HeI5876     0.3863      0.14     -29     1
# Comp:  2          [OIII]5007_d      2.227      0.18     -29     1
# Comp:  2            [OI]6300_d     0.5543      0.18     -29     1
# Comp:  2           [NII]6583_d      3.532      0.18     -29     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        39
#  comp.  1:       -25        27
#  comp.  2:       -28        15
# chi2/DOF: 0.6068; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.094      0.15     -25    27
# Comp:  1                Halpha      7.613      0.15     -25    27
# Comp:  2             [SII]6716      2.388      0.14     -28    15
# Comp:  2             [SII]6731      1.934      0.14     -28    15
# Comp:  2              HeII4687    0.08769      0.14     -28    15
# Comp:  2               HeI5876     0.3622      0.14     -28    15
# Comp:  2          [OIII]5007_d      2.368      0.18     -28    15
# Comp:  2            [OI]6300_d     0.5189      0.18     -28    15
# Comp:  2           [NII]6583_d      3.750      0.18     -28    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        48
#  comp.  1:       -26        29
#  comp.  2:       -29         1
# chi2/DOF: 0.6085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.574      0.15     -26    29
# Comp:  1                Halpha      7.786      0.15     -26    29
# Comp:  2             [SII]6716      2.340      0.14     -29     1
# Comp:  2             [SII]6731      1.711      0.14     -29     1
# Comp:  2              HeII4687    0.06035      0.14     -29     1
# Comp:  2               HeI5876     0.3313      0.14     -29     1
# Comp:  2          [OIII]5007_d      2.297      0.18     -29     1
# Comp:  2            [OI]6300_d     0.5198      0.18     -29     1
# Comp:  2           [NII]6583_d      3.586      0.18     -29     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        58
#  comp.  1:       -26        22
#  comp.  2:       -30        22
# chi2/DOF: 0.6073; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.204      0.15     -26    22
# Comp:  1                Halpha      7.455      0.15     -26    22
# Comp:  2             [SII]6716      2.423      0.15     -30    22
# Comp:  2             [SII]6731      1.771      0.15     -30    22
# Comp:  2              HeII4687      0.000      0.15     -30    22
# Comp:  2               HeI5876     0.3691      0.15     -30    22
# Comp:  2          [OIII]5007_d      2.399      0.18     -30    22
# Comp:  2            [OI]6300_d     0.5642      0.18     -30    22
# Comp:  2           [NII]6583_d      3.741      0.18     -30    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        49
#  comp.  1:       -26        20
#  comp.  2:       -28         8
# chi2/DOF: 0.6079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.151      0.15     -26    20
# Comp:  1                Halpha      7.515      0.15     -26    20
# Comp:  2             [SII]6716      2.379      0.14     -28     8
# Comp:  2             [SII]6731      1.716      0.14     -28     8
# Comp:  2              HeII4687     0.1954      0.14     -28     8
# Comp:  2               HeI5876     0.3547      0.14     -28     8
# Comp:  2          [OIII]5007_d      2.212      0.18     -28     8
# Comp:  2            [OI]6300_d     0.3713      0.18     -28     8
# Comp:  2           [NII]6583_d      3.610      0.18     -28     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        58
#  comp.  1:       -25        30
#  comp.  2:       -30        24
# chi2/DOF: 0.6041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.399      0.15     -25    30
# Comp:  1                Halpha      7.622      0.15     -25    30
# Comp:  2             [SII]6716      2.424      0.15     -30    24
# Comp:  2             [SII]6731      1.874      0.15     -30    24
# Comp:  2              HeII4687     0.2077      0.15     -30    24
# Comp:  2               HeI5876     0.4019      0.15     -30    24
# Comp:  2          [OIII]5007_d      2.372      0.19     -30    24
# Comp:  2            [OI]6300_d     0.4472      0.19     -30    24
# Comp:  2           [NII]6583_d      3.746      0.19     -30    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        43
#  comp.  1:       -25        27
#  comp.  2:       -27        21
# chi2/DOF: 0.5993; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.129      0.15     -25    27
# Comp:  1                Halpha      7.700      0.15     -25    27
# Comp:  2             [SII]6716      2.447      0.15     -27    21
# Comp:  2             [SII]6731      1.753      0.15     -27    21
# Comp:  2              HeII4687     0.1158      0.15     -27    21
# Comp:  2               HeI5876     0.4108      0.15     -27    21
# Comp:  2          [OIII]5007_d      2.279      0.18     -27    21
# Comp:  2            [OI]6300_d     0.4502      0.18     -27    21
# Comp:  2           [NII]6583_d      3.693      0.18     -27    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        41
#  comp.  1:       -27        24
#  comp.  2:       -28        12
# chi2/DOF: 0.6012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.427      0.15     -27    24
# Comp:  1                Halpha      7.678      0.15     -27    24
# Comp:  2             [SII]6716      2.356      0.14     -28    12
# Comp:  2             [SII]6731      1.844      0.14     -28    12
# ...
# chi2/DOF: 0.6064; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.100      0.15     -24    27
# Comp:  1                Halpha      7.502      0.15     -24    27
# Comp:  2             [SII]6716      2.418      0.15     -27    18
# Comp:  2             [SII]6731      1.738      0.15     -27    18
# Comp:  2              HeII4687     0.3083      0.15     -27    18
# Comp:  2               HeI5876     0.3502      0.15     -27    18
# Comp:  2          [OIII]5007_d      2.328      0.18     -27    18
# Comp:  2            [OI]6300_d     0.4694      0.18     -27    18
# Comp:  2           [NII]6583_d      3.744      0.18     -27    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        44
#  comp.  1:       -25        30
#  comp.  2:       -27        20
# chi2/DOF: 0.6089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.534      0.15     -25    30
# Comp:  1                Halpha      7.637      0.15     -25    30
# Comp:  2             [SII]6716      2.403      0.15     -27    20
# Comp:  2             [SII]6731      1.841      0.15     -27    20
# Comp:  2              HeII4687     0.2062      0.15     -27    20
# Comp:  2               HeI5876     0.3236      0.15     -27    20
# Comp:  2          [OIII]5007_d      2.310      0.18     -27    20
# Comp:  2            [OI]6300_d     0.4402      0.18     -27    20
# Comp:  2           [NII]6583_d      3.732      0.18     -27    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        55
#  comp.  1:       -26        24
#  comp.  2:       -27        16
# chi2/DOF: 0.6075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.433      0.15     -26    24
# Comp:  1                Halpha      7.435      0.15     -26    24
# Comp:  2             [SII]6716      2.369      0.14     -27    16
# Comp:  2             [SII]6731      1.852      0.14     -27    16
# Comp:  2              HeII4687    0.06350      0.14     -27    16
# Comp:  2               HeI5876     0.3546      0.14     -27    16
# Comp:  2          [OIII]5007_d      2.359      0.18     -27    16
# Comp:  2            [OI]6300_d     0.5235      0.18     -27    16
# Comp:  2           [NII]6583_d      3.637      0.18     -27    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        40
#  comp.  1:       -23        27
#  comp.  2:       -29        21
# chi2/DOF: 0.6077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.183      0.15     -23    27
# Comp:  1                Halpha      7.557      0.15     -23    27
# Comp:  2             [SII]6716      2.423      0.15     -29    21
# Comp:  2             [SII]6731      1.964      0.15     -29    21
# Comp:  2              HeII4687     0.2001      0.15     -29    21
# Comp:  2               HeI5876     0.3492      0.15     -29    21
# Comp:  2          [OIII]5007_d      2.292      0.18     -29    21
# Comp:  2            [OI]6300_d     0.5140      0.18     -29    21
# Comp:  2           [NII]6583_d      3.736      0.18     -29    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        45
#  comp.  1:       -26        22
#  comp.  2:       -30        18
# chi2/DOF: 0.6090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.249      0.15     -26    22
# Comp:  1                Halpha      7.536      0.15     -26    22
# Comp:  2             [SII]6716      2.364      0.15     -30    18
# Comp:  2             [SII]6731      1.801      0.15     -30    18
# Comp:  2              HeII4687      0.000      0.15     -30    18
# Comp:  2               HeI5876     0.4315      0.15     -30    18
# Comp:  2          [OIII]5007_d      2.358      0.18     -30    18
# Comp:  2            [OI]6300_d     0.5475      0.18     -30    18
# Comp:  2           [NII]6583_d      3.684      0.18     -30    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        39
#  comp.  1:       -25        25
#  comp.  2:       -31        18
# chi2/DOF: 0.6079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.120      0.15     -25    25
# Comp:  1                Halpha      7.591      0.15     -25    25
# Comp:  2             [SII]6716      2.339      0.15     -31    18
# Comp:  2             [SII]6731      1.704      0.15     -31    18
# Comp:  2              HeII4687     0.1749      0.15     -31    18
# Comp:  2               HeI5876     0.3987      0.15     -31    18
# Comp:  2          [OIII]5007_d      2.263      0.18     -31    18
# Comp:  2            [OI]6300_d     0.5059      0.18     -31    18
# Comp:  2           [NII]6583_d      3.668      0.18     -31    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        58
#  comp.  1:       -27        25
#  comp.  2:       -27         7
# chi2/DOF: 0.6056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.418      0.15     -27    25
# Comp:  1                Halpha      7.529      0.15     -27    25
# Comp:  2             [SII]6716      2.323      0.14     -27     7
# Comp:  2             [SII]6731      1.820      0.14     -27     7
# Comp:  2              HeII4687      0.000      0.14     -27     7
# Comp:  2               HeI5876     0.3630      0.14     -27     7
# Comp:  2          [OIII]5007_d      2.416      0.18     -27     7
# Comp:  2            [OI]6300_d     0.5196      0.18     -27     7
# Comp:  2           [NII]6583_d      3.479      0.18     -27     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        55
#  comp.  1:       -26        27
#  comp.  2:       -28        22
# chi2/DOF: 0.6041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.383      0.15     -26    27
# Comp:  1                Halpha      7.713      0.15     -26    27
# Comp:  2             [SII]6716      2.370      0.15     -28    22
# Comp:  2             [SII]6731      1.718      0.15     -28    22
# Comp:  2              HeII4687    0.09102      0.15     -28    22
# Comp:  2               HeI5876     0.4017      0.15     -28    22
# Comp:  2          [OIII]5007_d      2.306      0.18     -28    22
# Comp:  2            [OI]6300_d     0.4776      0.18     -28    22
# Comp:  2           [NII]6583_d      3.722      0.18     -28    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        43
#  comp.  1:       -24        25
#  comp.  2:       -31        19
# chi2/DOF: 0.6072; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.237      0.15     -24    25
# Comp:  1                Halpha      7.611      0.15     -24    25
# Comp:  2             [SII]6716      2.411      0.15     -31    19
# Comp:  2             [SII]6731      1.770      0.15     -31    19
# Comp:  2              HeII4687     0.1750      0.15     -31    19
# Comp:  2               HeI5876     0.3409      0.15     -31    19
# Comp:  2          [OIII]5007_d      2.354      0.18     -31    19
# Comp:  2            [OI]6300_d     0.4596      0.18     -31    19
# Comp:  2           [NII]6583_d      3.642      0.18     -31    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        47
#  comp.  1:       -25        26
#  comp.  2:       -30         9
# chi2/DOF: 0.6088; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.473      0.15     -25    26
# Comp:  1                Halpha      7.654      0.15     -25    26
# Comp:  2             [SII]6716      2.341      0.14     -30     9
# Comp:  2             [SII]6731      1.914      0.14     -30     9
# Comp:  2              HeII4687     0.1355      0.14     -30     9
# Comp:  2               HeI5876     0.4375      0.14     -30     9
# Comp:  2          [OIII]5007_d      2.161      0.18     -30     9
# Comp:  2            [OI]6300_d     0.5323      0.18     -30     9
# Comp:  2           [NII]6583_d      3.632      0.18     -30     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        40
#  comp.  1:       -25        31
#  comp.  2:       -29        10
# chi2/DOF: 0.6068; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.325      0.15     -25    31
# Comp:  1                Halpha      7.712      0.15     -25    31
# Comp:  2             [SII]6716      2.334      0.14     -29    10
# Comp:  2             [SII]6731      1.795      0.14     -29    10
# Comp:  2              HeII4687     0.1833      0.14     -29    10
# Comp:  2               HeI5876     0.4072      0.14     -29    10
# Comp:  2          [OIII]5007_d      2.342      0.18     -29    10
# Comp:  2            [OI]6300_d     0.5297      0.18     -29    10
# Comp:  2           [NII]6583_d      3.502      0.18     -29    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        39
#  comp.  1:       -24        29
#  comp.  2:       -31        13
# chi2/DOF: 0.6089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.197      0.15     -24    29
# Comp:  1                Halpha      7.625      0.15     -24    29
# Comp:  2             [SII]6716      2.359      0.14     -31    13
# Comp:  2             [SII]6731      1.936      0.14     -31    13
# Comp:  2              HeII4687     0.1892      0.14     -31    13
# Comp:  2               HeI5876     0.4276      0.14     -31    13
# Comp:  2          [OIII]5007_d      2.167      0.18     -31    13
# Comp:  2            [OI]6300_d     0.5534      0.18     -31    13
# Comp:  2           [NII]6583_d      3.611      0.18     -31    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        55
#  comp.  1:       -24        29
#  comp.  2:       -30        22
# chi2/DOF: 0.6055; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.545      0.15     -24    29
# Comp:  1                Halpha      7.791      0.15     -24    29
# Comp:  2             [SII]6716      2.413      0.15     -30    22
# Comp:  2             [SII]6731      1.982      0.15     -30    22
# Comp:  2              HeII4687     0.2940      0.15     -30    22
# Comp:  2               HeI5876     0.3541      0.15     -30    22
# Comp:  2          [OIII]5007_d      2.349      0.19     -30    22
# Comp:  2            [OI]6300_d     0.5148      0.19     -30    22
# Comp:  2           [NII]6583_d      3.833      0.19     -30    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        50
#  comp.  1:       -26        29
#  comp.  2:       -28        28
# chi2/DOF: 0.6089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.170      0.15     -26    29
# Comp:  1                Halpha      7.677      0.15     -26    29
# Comp:  2             [SII]6716      2.480      0.15     -28    28
# Comp:  2             [SII]6731      1.881      0.15     -28    28
# Comp:  2              HeII4687     0.2958      0.15     -28    28
# Comp:  2               HeI5876     0.4791      0.15     -28    28
# Comp:  2          [OIII]5007_d      2.388      0.19     -28    28
# Comp:  2            [OI]6300_d     0.5616      0.19     -28    28
# Comp:  2           [NII]6583_d      3.787      0.19     -28    28
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_5_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_5_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_5_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_5_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
