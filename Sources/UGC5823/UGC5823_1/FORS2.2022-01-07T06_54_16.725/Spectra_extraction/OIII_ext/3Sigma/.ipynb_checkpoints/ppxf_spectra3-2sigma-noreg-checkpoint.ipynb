# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt")
z = red[2][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.01875

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18488344 2.18560982 2.1863362  ... 3.48147239 3.48219877 3.48292515]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
# chi2/DOF: 0.005947; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         6
# chi2/DOF: 0.003687; DOF: 1905; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-19.82789048,   6.36898542])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         3
#  comp.  1:       -32        28
#  comp.  2:       -35        25
# chi2/DOF: 0.8206; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.95      0.19     -32    28
# Comp:  1                Halpha      46.86      0.19     -32    28
# Comp:  2             [SII]6716      8.841      0.19     -35    25
# Comp:  2             [SII]6731      6.498      0.19     -35    25
# Comp:  2              HeII4687    0.05959      0.19     -35    25
# Comp:  2               HeI5876      1.819      0.19     -35    25
# Comp:  2          [OIII]5007_d      14.52      0.24     -35    25
# Comp:  2            [OI]6300_d      1.230      0.24     -35    25
# Comp:  2           [NII]6583_d      16.20      0.24     -35    25
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  91.56; gas flux:     17 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  246.9; gas flux:     64 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  45.88; gas flux:     12 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  35.51; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.3065; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  9.504; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  58.81; gas flux:     15 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.087; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  65.16; gas flux:     22 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         1        48
#  comp.  1:       -31        35
#  comp.  2:       -35        17
# chi2/DOF: 0.7548; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.51      0.19     -31    35
# Comp:  1                Halpha      48.62      0.19     -31    35
# Comp:  2             [SII]6716      8.689      0.19     -35    17
# Comp:  2             [SII]6731      6.672      0.19     -35    17
# Comp:  2              HeII4687     0.1442      0.19     -35    17
# Comp:  2               HeI5876      1.879      0.19     -35    17
# Comp:  2          [OIII]5007_d      14.20      0.23     -35    17
# Comp:  2            [OI]6300_d     0.9946      0.23     -35    17
# Comp:  2           [NII]6583_d      16.00      0.23     -35    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       -31        29
#  comp.  2:       -35        18
# chi2/DOF: 0.7903; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.95      0.19     -31    29
# Comp:  1                Halpha      47.24      0.19     -31    29
# Comp:  2             [SII]6716      8.730      0.19     -35    18
# Comp:  2             [SII]6731      6.249      0.19     -35    18
# Comp:  2              HeII4687   0.001774      0.19     -35    18
# Comp:  2               HeI5876      1.984      0.19     -35    18
# Comp:  2          [OIII]5007_d      14.27      0.23     -35    18
# Comp:  2            [OI]6300_d      1.183      0.23     -35    18
# Comp:  2           [NII]6583_d      15.72      0.23     -35    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        21
#  comp.  1:       -34        25
#  comp.  2:       -33        30
# chi2/DOF: 0.7762; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.25      0.19     -34    25
# Comp:  1                Halpha      46.69      0.19     -34    25
# Comp:  2             [SII]6716      8.697      0.19     -33    30
# Comp:  2             [SII]6731      7.059      0.19     -33    30
# Comp:  2              HeII4687    0.09773      0.19     -33    30
# Comp:  2               HeI5876      1.777      0.19     -33    30
# Comp:  2          [OIII]5007_d      14.30      0.24     -33    30
# Comp:  2            [OI]6300_d      1.002      0.24     -33    30
# Comp:  2           [NII]6583_d      16.60      0.24     -33    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -32        23
#  comp.  2:       -35        17
# chi2/DOF: 0.7914; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.70      0.19     -32    23
# Comp:  1                Halpha      45.82      0.19     -32    23
# Comp:  2             [SII]6716      8.851      0.19     -35    17
# Comp:  2             [SII]6731      6.390      0.19     -35    17
# Comp:  2              HeII4687    0.04103      0.19     -35    17
# Comp:  2               HeI5876      1.759      0.19     -35    17
# Comp:  2          [OIII]5007_d      13.73      0.23     -35    17
# Comp:  2            [OI]6300_d      1.115      0.23     -35    17
# Comp:  2           [NII]6583_d      15.92      0.23     -35    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:       -35        19
#  comp.  2:       -35        21
# chi2/DOF: 0.7512; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.45      0.19     -35    19
# Comp:  1                Halpha      45.86      0.19     -35    19
# Comp:  2             [SII]6716      8.827      0.19     -35    21
# Comp:  2             [SII]6731      6.101      0.19     -35    21
# Comp:  2              HeII4687    0.04656      0.19     -35    21
# Comp:  2               HeI5876      1.700      0.19     -35    21
# Comp:  2          [OIII]5007_d      14.80      0.24     -35    21
# Comp:  2            [OI]6300_d      1.240      0.24     -35    21
# Comp:  2           [NII]6583_d      16.08      0.24     -35    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        41
#  comp.  1:       -33        20
#  comp.  2:       -32        32
# chi2/DOF: 0.7634; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.31      0.19     -33    20
# Comp:  1                Halpha      46.10      0.19     -33    20
# Comp:  2             [SII]6716      8.928      0.19     -32    32
# Comp:  2             [SII]6731      6.638      0.19     -32    32
# Comp:  2              HeII4687    0.02075      0.19     -32    32
# Comp:  2               HeI5876      2.027      0.19     -32    32
# Comp:  2          [OIII]5007_d      14.46      0.24     -32    32
# Comp:  2            [OI]6300_d     0.9581      0.24     -32    32
# Comp:  2           [NII]6583_d      16.71      0.24     -32    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        27
#  comp.  1:       -30        33
#  comp.  2:       -38        21
# chi2/DOF: 0.7822; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.97      0.19     -30    33
# Comp:  1                Halpha      47.93      0.19     -30    33
# Comp:  2             [SII]6716      8.674      0.19     -38    21
# Comp:  2             [SII]6731      6.759      0.19     -38    21
# Comp:  2              HeII4687      0.000      0.19     -38    21
# Comp:  2               HeI5876      1.842      0.19     -38    21
# Comp:  2          [OIII]5007_d      14.14      0.24     -38    21
# Comp:  2            [OI]6300_d      1.147      0.24     -38    21
# Comp:  2           [NII]6583_d      15.82      0.24     -38    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        32
#  comp.  1:       -34        21
#  comp.  2:       -32        32
# chi2/DOF: 0.7531; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.71      0.19     -34    21
# Comp:  1                Halpha      45.82      0.19     -34    21
# Comp:  2             [SII]6716      9.212      0.19     -32    32
# Comp:  2             [SII]6731      6.697      0.19     -32    32
# Comp:  2              HeII4687     0.1669      0.19     -32    32
# Comp:  2               HeI5876      2.018      0.19     -32    32
# Comp:  2          [OIII]5007_d      14.46      0.24     -32    32
# Comp:  2            [OI]6300_d      1.419      0.24     -32    32
# Comp:  2           [NII]6583_d      16.64      0.24     -32    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        37
#  comp.  1:       -32        20
#  comp.  2:       -33        27
# chi2/DOF: 0.7696; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.68      0.19     -32    20
# Comp:  1                Halpha      45.73      0.19     -32    20
# Comp:  2             [SII]6716      9.145      0.19     -33    27
# Comp:  2             [SII]6731      6.420      0.19     -33    27
# Comp:  2              HeII4687     0.1027      0.19     -33    27
# Comp:  2               HeI5876      2.048      0.19     -33    27
# Comp:  2          [OIII]5007_d      14.60      0.24     -33    27
# Comp:  2            [OI]6300_d      1.130      0.24     -33    27
# Comp:  2           [NII]6583_d      16.38      0.24     -33    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        11
#  comp.  1:       -30        36
#  comp.  2:       -36        19
# chi2/DOF: 0.7464; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.49      0.19     -30    36
# Comp:  1                Halpha      48.96      0.19     -30    36
# Comp:  2             [SII]6716      8.710      0.19     -36    19
# Comp:  2             [SII]6731      6.471      0.19     -36    19
# Comp:  2              HeII4687   0.001965      0.19     -36    19
# Comp:  2               HeI5876      1.992      0.19     -36    19
# Comp:  2          [OIII]5007_d      14.23      0.24     -36    19
# Comp:  2            [OI]6300_d      1.525      0.24     -36    19
# Comp:  2           [NII]6583_d      15.64      0.24     -36    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        37
#  comp.  1:       -35        21
#  comp.  2:       -35        21
# chi2/DOF: 0.7660; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.52      0.19     -35    21
# Comp:  1                Halpha      46.03      0.19     -35    21
# Comp:  2             [SII]6716      8.966      0.19     -35    21
# Comp:  2             [SII]6731      6.415      0.19     -35    21
# Comp:  2              HeII4687    0.09927      0.19     -35    21
# Comp:  2               HeI5876      1.746      0.19     -35    21
# Comp:  2          [OIII]5007_d      13.83      0.24     -35    21
# Comp:  2            [OI]6300_d      1.248      0.24     -35    21
# Comp:  2           [NII]6583_d      16.33      0.24     -35    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -31        37
#  comp.  2:       -38        21
# chi2/DOF: 0.7387; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.74      0.20     -31    37
# Comp:  1                Halpha      48.91      0.20     -31    37
# Comp:  2             [SII]6716      8.731      0.19     -38    21
# Comp:  2             [SII]6731      6.469      0.19     -38    21
# Comp:  2              HeII4687    0.06179      0.19     -38    21
# Comp:  2               HeI5876      2.084      0.19     -38    21
# Comp:  2          [OIII]5007_d      13.56      0.24     -38    21
# Comp:  2            [OI]6300_d      1.268      0.24     -38    21
# Comp:  2           [NII]6583_d      15.91      0.24     -38    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -34        27
#  comp.  2:       -36        24
# chi2/DOF: 0.8031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.01      0.19     -34    27
# Comp:  1                Halpha      46.81      0.19     -34    27
# Comp:  2             [SII]6716      8.905      0.19     -36    24
# Comp:  2             [SII]6731      6.849      0.19     -36    24
# Comp:  2              HeII4687     0.1142      0.19     -36    24
# Comp:  2               HeI5876      2.004      0.19     -36    24
# Comp:  2          [OIII]5007_d      14.32      0.24     -36    24
# Comp:  2            [OI]6300_d      1.277      0.24     -36    24
# Comp:  2           [NII]6583_d      16.20      0.24     -36    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       -31        32
#  comp.  2:       -34        32
# chi2/DOF: 0.7774; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.33      0.19     -31    32
# Comp:  1                Halpha      47.84      0.19     -31    32
# Comp:  2             [SII]6716      9.101      0.19     -34    32
# Comp:  2             [SII]6731      6.566      0.19     -34    32
# Comp:  2              HeII4687    0.04435      0.19     -34    32
# Comp:  2               HeI5876      1.979      0.19     -34    32
# Comp:  2          [OIII]5007_d      14.88      0.24     -34    32
# Comp:  2            [OI]6300_d      1.321      0.24     -34    32
# Comp:  2           [NII]6583_d      16.75      0.24     -34    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       -33        15
#  comp.  2:       -36        19
# chi2/DOF: 0.7224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.24      0.18     -33    15
# Comp:  1                Halpha      44.80      0.18     -33    15
# Comp:  2             [SII]6716      8.754      0.19     -36    19
# Comp:  2             [SII]6731      5.948      0.19     -36    19
# Comp:  2              HeII4687      0.000      0.19     -36    19
# Comp:  2               HeI5876      1.796      0.19     -36    19
# Comp:  2          [OIII]5007_d      14.46      0.24     -36    19
# Comp:  2            [OI]6300_d      1.184      0.24     -36    19
# Comp:  2           [NII]6583_d      15.96      0.24     -36    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -31        23
#  comp.  2:       -34        32
# chi2/DOF: 0.7899; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.29      0.19     -31    23
# Comp:  1                Halpha      46.25      0.19     -31    23
# Comp:  2             [SII]6716      8.779      0.19     -34    32
# Comp:  2             [SII]6731      6.290      0.19     -34    32
# Comp:  2              HeII4687     0.1137      0.19     -34    32
# Comp:  2               HeI5876      2.011      0.19     -34    32
# Comp:  2          [OIII]5007_d      15.43      0.24     -34    32
# Comp:  2            [OI]6300_d      1.022      0.24     -34    32
# Comp:  2           [NII]6583_d      16.69      0.24     -34    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        45
#  comp.  1:       -34        23
#  comp.  2:       -35        16
# chi2/DOF: 0.7688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.95      0.19     -34    23
# Comp:  1                Halpha      45.37      0.19     -34    23
# Comp:  2             [SII]6716      8.987      0.19     -35    16
# Comp:  2             [SII]6731      6.380      0.19     -35    16
# Comp:  2              HeII4687    0.07679      0.19     -35    16
# Comp:  2               HeI5876      1.944      0.19     -35    16
# Comp:  2          [OIII]5007_d      13.53      0.23     -35    16
# Comp:  2            [OI]6300_d     0.9292      0.23     -35    16
# Comp:  2           [NII]6583_d      15.91      0.23     -35    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -32        34
#  comp.  2:       -33        27
# chi2/DOF: 0.7770; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.58      0.19     -32    34
# Comp:  1                Halpha      47.91      0.19     -32    34
# Comp:  2             [SII]6716      8.891      0.19     -33    27
# Comp:  2             [SII]6731      6.066      0.19     -33    27
# Comp:  2              HeII4687    0.04486      0.19     -33    27
# Comp:  2               HeI5876      2.044      0.19     -33    27
# Comp:  2          [OIII]5007_d      15.25      0.24     -33    27
# Comp:  2            [OI]6300_d      1.131      0.24     -33    27
# Comp:  2           [NII]6583_d      16.33      0.24     -33    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -34        22
#  comp.  2:       -33        17
# chi2/DOF: 0.7819; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.84      0.19     -34    22
# Comp:  1                Halpha      46.13      0.19     -34    22
# Comp:  2             [SII]6716      8.975      0.19     -33    17
# Comp:  2             [SII]6731      6.369      0.19     -33    17
# Comp:  2              HeII4687    0.07701      0.19     -33    17
# Comp:  2               HeI5876      1.829      0.19     -33    17
# Comp:  2          [OIII]5007_d      14.34      0.23     -33    17
# Comp:  2            [OI]6300_d      1.421      0.23     -33    17
# Comp:  2           [NII]6583_d      15.86      0.23     -33    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -34        24
#  comp.  2:       -36        32
# chi2/DOF: 0.7857; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.91      0.19     -34    24
# Comp:  1                Halpha      46.46      0.19     -34    24
# Comp:  2             [SII]6716      8.736      0.19     -36    32
# Comp:  2             [SII]6731      6.974      0.19     -36    32
# Comp:  2              HeII4687      0.000      0.19     -36    32
# Comp:  2               HeI5876      1.777      0.19     -36    32
# Comp:  2          [OIII]5007_d      14.65      0.24     -36    32
# Comp:  2            [OI]6300_d      1.249      0.24     -36    32
# Comp:  2           [NII]6583_d      16.63      0.24     -36    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        28
#  comp.  1:       -33        23
#  comp.  2:       -35        26
# chi2/DOF: 0.7832; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.56      0.19     -33    23
# Comp:  1                Halpha      46.68      0.19     -33    23
# Comp:  2             [SII]6716      9.005      0.19     -35    26
# Comp:  2             [SII]6731      6.954      0.19     -35    26
# Comp:  2              HeII4687    0.05492      0.19     -35    26
# Comp:  2               HeI5876      1.958      0.19     -35    26
# Comp:  2          [OIII]5007_d      14.89      0.24     -35    26
# Comp:  2            [OI]6300_d      1.398      0.24     -35    26
# Comp:  2           [NII]6583_d      16.20      0.24     -35    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -34        22
#  comp.  2:       -36        21
# chi2/DOF: 0.7764; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.85      0.19     -34    22
# Comp:  1                Halpha      45.28      0.19     -34    22
# Comp:  2             [SII]6716      8.789      0.19     -36    21
# Comp:  2             [SII]6731      6.419      0.19     -36    21
# Comp:  2              HeII4687    0.03324      0.19     -36    21
# Comp:  2               HeI5876      1.758      0.19     -36    21
# Comp:  2          [OIII]5007_d      14.52      0.24     -36    21
# Comp:  2            [OI]6300_d      1.488      0.24     -36    21
# Comp:  2           [NII]6583_d      15.97      0.24     -36    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        45
#  comp.  1:       -30        36
#  comp.  2:       -33        31
# chi2/DOF: 0.7473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.05      0.19     -30    36
# Comp:  1                Halpha      48.88      0.19     -30    36
# Comp:  2             [SII]6716      8.910      0.19     -33    31
# Comp:  2             [SII]6731      6.709      0.19     -33    31
# Comp:  2              HeII4687      0.000      0.19     -33    31
# Comp:  2               HeI5876      1.741      0.19     -33    31
# Comp:  2          [OIII]5007_d      15.16      0.24     -33    31
# Comp:  2            [OI]6300_d      1.520      0.24     -33    31
# Comp:  2           [NII]6583_d      16.67      0.24     -33    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -34        27
#  comp.  2:       -38        24
# chi2/DOF: 0.7980; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.37      0.19     -34    27
# Comp:  1                Halpha      46.84      0.19     -34    27
# Comp:  2             [SII]6716      9.053      0.19     -38    24
# Comp:  2             [SII]6731      6.506      0.19     -38    24
# Comp:  2              HeII4687     0.1087      0.19     -38    24
# Comp:  2               HeI5876      1.758      0.19     -38    24
# Comp:  2          [OIII]5007_d      14.88      0.24     -38    24
# Comp:  2            [OI]6300_d      1.129      0.24     -38    24
# Comp:  2           [NII]6583_d      16.10      0.24     -38    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -30        35
#  comp.  2:       -33        38
# chi2/DOF: 0.7347; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.25      0.19     -30    35
# Comp:  1                Halpha      47.82      0.19     -30    35
# Comp:  2             [SII]6716      9.501      0.20     -33    38
# Comp:  2             [SII]6731      6.439      0.20     -33    38
# Comp:  2              HeII4687     0.1171      0.20     -33    38
# Comp:  2               HeI5876      1.989      0.20     -33    38
# Comp:  2          [OIII]5007_d      15.72      0.25     -33    38
# Comp:  2            [OI]6300_d      1.170      0.25     -33    38
# Comp:  2           [NII]6583_d      17.10      0.25     -33    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        52
#  comp.  1:       -33        17
#  comp.  2:       -35        31
# chi2/DOF: 0.7369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.69      0.19     -33    17
# Comp:  1                Halpha      45.53      0.19     -33    17
# Comp:  2             [SII]6716      8.757      0.19     -35    31
# Comp:  2             [SII]6731      6.654      0.19     -35    31
# Comp:  2              HeII4687    0.04081      0.19     -35    31
# Comp:  2               HeI5876      1.811      0.19     -35    31
# Comp:  2          [OIII]5007_d      15.78      0.24     -35    31
# Comp:  2            [OI]6300_d      1.247      0.24     -35    31
# Comp:  2           [NII]6583_d      16.80      0.24     -35    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        13
#  comp.  1:       -36        24
#  comp.  2:       -36        28
# chi2/DOF: 0.7543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.62      0.19     -36    24
# Comp:  1                Halpha      46.46      0.19     -36    24
# Comp:  2             [SII]6716      8.893      0.19     -36    28
# Comp:  2             [SII]6731      6.170      0.19     -36    28
# Comp:  2              HeII4687     0.1303      0.19     -36    28
# Comp:  2               HeI5876      2.094      0.19     -36    28
# Comp:  2          [OIII]5007_d      14.96      0.24     -36    28
# Comp:  2            [OI]6300_d      1.171      0.24     -36    28
# Comp:  2           [NII]6583_d      16.15      0.24     -36    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -33        26
#  comp.  2:       -37        24
# chi2/DOF: 0.8013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.16      0.19     -33    26
# Comp:  1                Halpha      46.58      0.19     -33    26
# Comp:  2             [SII]6716      9.004      0.19     -37    24
# Comp:  2             [SII]6731      6.801      0.19     -37    24
# Comp:  2              HeII4687   0.005155      0.19     -37    24
# Comp:  2               HeI5876      1.709      0.19     -37    24
# Comp:  2          [OIII]5007_d      13.93      0.24     -37    24
# Comp:  2            [OI]6300_d      1.492      0.24     -37    24
# Comp:  2           [NII]6583_d      15.98      0.24     -37    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -33        26
#  comp.  2:       -32        31
# chi2/DOF: 0.7959; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.96      0.19     -33    26
# Comp:  1                Halpha      46.93      0.19     -33    26
# Comp:  2             [SII]6716      8.961      0.19     -32    31
# Comp:  2             [SII]6731      6.669      0.19     -32    31
# Comp:  2              HeII4687      0.000      0.19     -32    31
# Comp:  2               HeI5876      2.060      0.19     -32    31
# Comp:  2          [OIII]5007_d      14.44      0.24     -32    31
# Comp:  2            [OI]6300_d      1.065      0.24     -32    31
# Comp:  2           [NII]6583_d      16.64      0.24     -32    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        32
#  comp.  1:       -34        16
#  comp.  2:       -37        16
# chi2/DOF: 0.7316; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.01      0.19     -34    16
# Comp:  1                Halpha      45.29      0.19     -34    16
# Comp:  2             [SII]6716      8.432      0.19     -37    16
# Comp:  2             [SII]6731      6.490      0.19     -37    16
# Comp:  2              HeII4687     0.1167      0.19     -37    16
# Comp:  2               HeI5876      1.966      0.19     -37    16
# Comp:  2          [OIII]5007_d      14.56      0.23     -37    16
# Comp:  2            [OI]6300_d      1.455      0.23     -37    16
# Comp:  2           [NII]6583_d      15.71      0.23     -37    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -30        33
#  comp.  2:       -34        31
# chi2/DOF: 0.7814; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.71      0.19     -30    33
# Comp:  1                Halpha      47.61      0.19     -30    33
# Comp:  2             [SII]6716      8.783      0.19     -34    31
# Comp:  2             [SII]6731      7.035      0.19     -34    31
# Comp:  2              HeII4687    0.01799      0.19     -34    31
# Comp:  2               HeI5876      1.677      0.19     -34    31
# Comp:  2          [OIII]5007_d      14.60      0.24     -34    31
# Comp:  2            [OI]6300_d      1.257      0.24     -34    31
# Comp:  2           [NII]6583_d      16.56      0.24     -34    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        25
#  comp.  1:       -32        22
#  comp.  2:       -31        27
# chi2/DOF: 0.7718; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.65      0.19     -32    22
# Comp:  1                Halpha      46.23      0.19     -32    22
# Comp:  2             [SII]6716      8.951      0.19     -31    27
# Comp:  2             [SII]6731      6.800      0.19     -31    27
# Comp:  2              HeII4687      0.000      0.19     -31    27
# Comp:  2               HeI5876      1.842      0.19     -31    27
# Comp:  2          [OIII]5007_d      15.31      0.24     -31    27
# Comp:  2            [OI]6300_d      1.230      0.24     -31    27
# Comp:  2           [NII]6583_d      16.34      0.24     -31    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        40
#  comp.  1:       -32        21
#  comp.  2:       -32        27
# chi2/DOF: 0.7850; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.87      0.19     -32    21
# Comp:  1                Halpha      46.02      0.19     -32    21
# Comp:  2             [SII]6716      8.996      0.19     -32    27
# Comp:  2             [SII]6731      6.036      0.19     -32    27
# Comp:  2              HeII4687      0.000      0.19     -32    27
# Comp:  2               HeI5876      1.638      0.19     -32    27
# Comp:  2          [OIII]5007_d      15.43      0.24     -32    27
# Comp:  2            [OI]6300_d      1.300      0.24     -32    27
# Comp:  2           [NII]6583_d      15.99      0.24     -32    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -32        20
#  comp.  2:       -32        23
# chi2/DOF: 0.7763; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.99      0.19     -32    20
# Comp:  1                Halpha      45.18      0.19     -32    20
# Comp:  2             [SII]6716      9.105      0.19     -32    23
# Comp:  2             [SII]6731      6.433      0.19     -32    23
# Comp:  2              HeII4687    0.08428      0.19     -32    23
# Comp:  2               HeI5876      2.015      0.19     -32    23
# Comp:  2          [OIII]5007_d      14.72      0.24     -32    23
# Comp:  2            [OI]6300_d      1.296      0.24     -32    23
# Comp:  2           [NII]6583_d      15.79      0.24     -32    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -35        23
#  comp.  2:       -36        18
# chi2/DOF: 0.7791; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.13      0.19     -35    23
# Comp:  1                Halpha      45.89      0.19     -35    23
# Comp:  2             [SII]6716      8.463      0.19     -36    18
# Comp:  2             [SII]6731      6.034      0.19     -36    18
# Comp:  2              HeII4687     0.1077      0.19     -36    18
# Comp:  2               HeI5876      1.965      0.19     -36    18
# Comp:  2          [OIII]5007_d      14.18      0.23     -36    18
# Comp:  2            [OI]6300_d      1.247      0.23     -36    18
# Comp:  2           [NII]6583_d      15.76      0.23     -36    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        25
#  comp.  1:       -31        33
#  comp.  2:       -35        25
# chi2/DOF: 0.7759; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.84      0.19     -31    33
# Comp:  1                Halpha      46.84      0.19     -31    33
# Comp:  2             [SII]6716      9.124      0.19     -35    25
# Comp:  2             [SII]6731      6.949      0.19     -35    25
# Comp:  2              HeII4687     0.1501      0.19     -35    25
# Comp:  2               HeI5876      1.997      0.19     -35    25
# Comp:  2          [OIII]5007_d      14.70      0.24     -35    25
# Comp:  2            [OI]6300_d      1.411      0.24     -35    25
# Comp:  2           [NII]6583_d      16.38      0.24     -35    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -33        32
#  comp.  2:       -34        20
# chi2/DOF: 0.7870; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.33      0.19     -33    32
# Comp:  1                Halpha      47.70      0.19     -33    32
# Comp:  2             [SII]6716      8.447      0.19     -34    20
# Comp:  2             [SII]6731      6.026      0.19     -34    20
# Comp:  2              HeII4687     0.1407      0.19     -34    20
# Comp:  2               HeI5876      1.543      0.19     -34    20
# Comp:  2          [OIII]5007_d      14.85      0.24     -34    20
# Comp:  2            [OI]6300_d      1.049      0.24     -34    20
# Comp:  2           [NII]6583_d      15.97      0.24     -34    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         6
#  comp.  1:       -33        17
#  comp.  2:       -34        31
# chi2/DOF: 0.7580; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.17      0.19     -33    17
# Comp:  1                Halpha      45.58      0.19     -33    17
# Comp:  2             [SII]6716      9.047      0.19     -34    31
# Comp:  2             [SII]6731      6.531      0.19     -34    31
# Comp:  2              HeII4687     0.1244      0.19     -34    31
# Comp:  2               HeI5876      1.665      0.19     -34    31
# Comp:  2          [OIII]5007_d      15.47      0.24     -34    31
# Comp:  2            [OI]6300_d      1.234      0.24     -34    31
# Comp:  2           [NII]6583_d      16.21      0.24     -34    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -32        18
#  comp.  2:       -33        22
# chi2/DOF: 0.7667; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.53      0.19     -32    18
# Comp:  1                Halpha      45.42      0.19     -32    18
# Comp:  2             [SII]6716      8.757      0.19     -33    22
# Comp:  2             [SII]6731      6.337      0.19     -33    22
# Comp:  2              HeII4687   0.003887      0.19     -33    22
# Comp:  2               HeI5876      1.782      0.19     -33    22
# Comp:  2          [OIII]5007_d      14.51      0.24     -33    22
# Comp:  2            [OI]6300_d     0.9458      0.24     -33    22
# Comp:  2           [NII]6583_d      15.97      0.24     -33    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -31        32
#  comp.  2:       -34        31
# chi2/DOF: 0.7643; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.24      0.19     -31    32
# Comp:  1                Halpha      47.21      0.19     -31    32
# Comp:  2             [SII]6716      8.831      0.19     -34    31
# Comp:  2             [SII]6731      6.281      0.19     -34    31
# Comp:  2              HeII4687     0.1215      0.19     -34    31
# Comp:  2               HeI5876      1.756      0.19     -34    31
# Comp:  2          [OIII]5007_d      15.30      0.24     -34    31
# Comp:  2            [OI]6300_d      1.137      0.24     -34    31
# Comp:  2           [NII]6583_d      16.24      0.24     -34    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -31        37
#  comp.  2:       -32        29
# chi2/DOF: 0.7419; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.77      0.20     -31    37
# Comp:  1                Halpha      48.74      0.20     -31    37
# Comp:  2             [SII]6716      9.095      0.19     -32    29
# Comp:  2             [SII]6731      6.468      0.19     -32    29
# Comp:  2              HeII4687     0.1230      0.19     -32    29
# Comp:  2               HeI5876      1.941      0.19     -32    29
# Comp:  2          [OIII]5007_d      14.35      0.24     -32    29
# Comp:  2            [OI]6300_d      1.285      0.24     -32    29
# Comp:  2           [NII]6583_d      16.52      0.24     -32    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        50
#  comp.  1:       -35        28
#  comp.  2:       -34        32
# chi2/DOF: 0.7646; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.93      0.19     -35    28
# Comp:  1                Halpha      47.08      0.19     -35    28
# Comp:  2             [SII]6716      8.690      0.19     -34    32
# Comp:  2             [SII]6731      6.667      0.19     -34    32
# ...
# chi2/DOF: 0.7977; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.18      0.19     -33    32
# Comp:  1                Halpha      47.42      0.19     -33    32
# Comp:  2             [SII]6716      8.881      0.19     -36    25
# Comp:  2             [SII]6731      6.946      0.19     -36    25
# Comp:  2              HeII4687   0.002150      0.19     -36    25
# Comp:  2               HeI5876      1.857      0.19     -36    25
# Comp:  2          [OIII]5007_d      13.97      0.24     -36    25
# Comp:  2            [OI]6300_d      1.084      0.24     -36    25
# Comp:  2           [NII]6583_d      16.39      0.24     -36    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -31        35
#  comp.  2:       -31        30
# chi2/DOF: 0.7516; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.47      0.19     -31    35
# Comp:  1                Halpha      48.57      0.19     -31    35
# Comp:  2             [SII]6716      9.121      0.19     -31    30
# Comp:  2             [SII]6731      7.012      0.19     -31    30
# Comp:  2              HeII4687      0.000      0.19     -31    30
# Comp:  2               HeI5876      2.224      0.19     -31    30
# Comp:  2          [OIII]5007_d      15.26      0.24     -31    30
# Comp:  2            [OI]6300_d      1.274      0.24     -31    30
# Comp:  2           [NII]6583_d      16.53      0.24     -31    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:       -30        32
#  comp.  2:       -37        23
# chi2/DOF: 0.7864; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.19      0.19     -30    32
# Comp:  1                Halpha      47.29      0.19     -30    32
# Comp:  2             [SII]6716      8.939      0.19     -37    23
# Comp:  2             [SII]6731      6.472      0.19     -37    23
# Comp:  2              HeII4687      0.000      0.19     -37    23
# Comp:  2               HeI5876      1.942      0.19     -37    23
# Comp:  2          [OIII]5007_d      13.95      0.24     -37    23
# Comp:  2            [OI]6300_d      1.458      0.24     -37    23
# Comp:  2           [NII]6583_d      16.42      0.24     -37    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -34        25
#  comp.  2:       -35        28
# chi2/DOF: 0.7837; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.00      0.19     -34    25
# Comp:  1                Halpha      46.37      0.19     -34    25
# Comp:  2             [SII]6716      8.915      0.19     -35    28
# Comp:  2             [SII]6731      6.553      0.19     -35    28
# Comp:  2              HeII4687    0.07138      0.19     -35    28
# Comp:  2               HeI5876      1.916      0.19     -35    28
# Comp:  2          [OIII]5007_d      14.17      0.24     -35    28
# Comp:  2            [OI]6300_d      1.170      0.24     -35    28
# Comp:  2           [NII]6583_d      16.62      0.24     -35    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         7
#  comp.  1:       -34        33
#  comp.  2:       -35        30
# chi2/DOF: 0.7859; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.87      0.19     -34    33
# Comp:  1                Halpha      47.95      0.19     -34    33
# Comp:  2             [SII]6716      8.607      0.19     -35    30
# Comp:  2             [SII]6731      6.913      0.19     -35    30
# Comp:  2              HeII4687     0.1340      0.19     -35    30
# Comp:  2               HeI5876      1.572      0.19     -35    30
# Comp:  2          [OIII]5007_d      14.52      0.24     -35    30
# Comp:  2            [OI]6300_d      1.034      0.24     -35    30
# Comp:  2           [NII]6583_d      16.65      0.24     -35    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        18
#  comp.  1:       -32        36
#  comp.  2:       -33        21
# chi2/DOF: 0.7584; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.81      0.19     -32    36
# Comp:  1                Halpha      48.32      0.19     -32    36
# Comp:  2             [SII]6716      8.986      0.19     -33    21
# Comp:  2             [SII]6731      6.438      0.19     -33    21
# Comp:  2              HeII4687      0.000      0.19     -33    21
# Comp:  2               HeI5876      1.820      0.19     -33    21
# Comp:  2          [OIII]5007_d      13.85      0.24     -33    21
# Comp:  2            [OI]6300_d      1.470      0.24     -33    21
# Comp:  2           [NII]6583_d      16.14      0.24     -33    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        13
#  comp.  1:       -33        17
#  comp.  2:       -33        23
# chi2/DOF: 0.7438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.44      0.19     -33    17
# Comp:  1                Halpha      45.28      0.19     -33    17
# Comp:  2             [SII]6716      8.687      0.19     -33    23
# Comp:  2             [SII]6731      6.774      0.19     -33    23
# Comp:  2              HeII4687    0.06998      0.19     -33    23
# Comp:  2               HeI5876      2.142      0.19     -33    23
# Comp:  2          [OIII]5007_d      14.37      0.24     -33    23
# Comp:  2            [OI]6300_d     0.9756      0.24     -33    23
# Comp:  2           [NII]6583_d      16.26      0.24     -33    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        13
#  comp.  1:       -32        34
#  comp.  2:       -37        19
# chi2/DOF: 0.7772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.03      0.19     -32    34
# Comp:  1                Halpha      48.43      0.19     -32    34
# Comp:  2             [SII]6716      8.696      0.19     -37    19
# Comp:  2             [SII]6731      6.487      0.19     -37    19
# Comp:  2              HeII4687    0.03699      0.19     -37    19
# Comp:  2               HeI5876      1.697      0.19     -37    19
# Comp:  2          [OIII]5007_d      14.80      0.24     -37    19
# Comp:  2            [OI]6300_d      1.094      0.24     -37    19
# Comp:  2           [NII]6583_d      15.71      0.24     -37    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        30
#  comp.  1:       -32        24
#  comp.  2:       -36        15
# chi2/DOF: 0.7622; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.06      0.19     -32    24
# Comp:  1                Halpha      46.89      0.19     -32    24
# Comp:  2             [SII]6716      8.295      0.19     -36    15
# Comp:  2             [SII]6731      6.752      0.19     -36    15
# Comp:  2              HeII4687      0.000      0.19     -36    15
# Comp:  2               HeI5876      2.030      0.19     -36    15
# Comp:  2          [OIII]5007_d      13.73      0.23     -36    15
# Comp:  2            [OI]6300_d      1.314      0.23     -36    15
# Comp:  2           [NII]6583_d      15.61      0.23     -36    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        52
#  comp.  1:       -35        25
#  comp.  2:       -36        20
# chi2/DOF: 0.7417; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.70      0.19     -35    25
# Comp:  1                Halpha      46.74      0.19     -35    25
# Comp:  2             [SII]6716      8.371      0.19     -36    20
# Comp:  2             [SII]6731      6.032      0.19     -36    20
# Comp:  2              HeII4687     0.1518      0.19     -36    20
# Comp:  2               HeI5876      1.979      0.19     -36    20
# Comp:  2          [OIII]5007_d      13.95      0.24     -36    20
# Comp:  2            [OI]6300_d      1.079      0.24     -36    20
# Comp:  2           [NII]6583_d      16.27      0.24     -36    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        29
#  comp.  1:       -35        22
#  comp.  2:       -33        27
# chi2/DOF: 0.7414; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.83      0.19     -35    22
# Comp:  1                Halpha      46.29      0.19     -35    22
# Comp:  2             [SII]6716      8.880      0.19     -33    27
# Comp:  2             [SII]6731      6.827      0.19     -33    27
# Comp:  2              HeII4687    0.06914      0.19     -33    27
# Comp:  2               HeI5876      1.929      0.19     -33    27
# Comp:  2          [OIII]5007_d      15.25      0.24     -33    27
# Comp:  2            [OI]6300_d      1.547      0.24     -33    27
# Comp:  2           [NII]6583_d      16.20      0.24     -33    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        20
#  comp.  1:       -34        33
#  comp.  2:       -34        25
# chi2/DOF: 0.7881; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.00      0.19     -34    33
# Comp:  1                Halpha      47.72      0.19     -34    33
# Comp:  2             [SII]6716      8.746      0.19     -34    25
# Comp:  2             [SII]6731      6.539      0.19     -34    25
# Comp:  2              HeII4687     0.1028      0.19     -34    25
# Comp:  2               HeI5876      1.957      0.19     -34    25
# Comp:  2          [OIII]5007_d      14.43      0.24     -34    25
# Comp:  2            [OI]6300_d      1.271      0.24     -34    25
# Comp:  2           [NII]6583_d      16.17      0.24     -34    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -33        23
#  comp.  2:       -35        29
# chi2/DOF: 0.7637; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.90      0.19     -33    23
# Comp:  1                Halpha      46.53      0.19     -33    23
# Comp:  2             [SII]6716      8.592      0.19     -35    29
# Comp:  2             [SII]6731      6.628      0.19     -35    29
# Comp:  2              HeII4687    0.01112      0.19     -35    29
# Comp:  2               HeI5876      1.862      0.19     -35    29
# Comp:  2          [OIII]5007_d      15.66      0.24     -35    29
# Comp:  2            [OI]6300_d      1.167      0.24     -35    29
# Comp:  2           [NII]6583_d      16.23      0.24     -35    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        20
#  comp.  1:       -31        32
#  comp.  2:       -33        26
# chi2/DOF: 0.7896; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.50      0.19     -31    32
# Comp:  1                Halpha      47.09      0.19     -31    32
# Comp:  2             [SII]6716      9.170      0.19     -33    26
# Comp:  2             [SII]6731      6.185      0.19     -33    26
# Comp:  2              HeII4687    0.07787      0.19     -33    26
# Comp:  2               HeI5876      1.891      0.19     -33    26
# Comp:  2          [OIII]5007_d      14.15      0.24     -33    26
# Comp:  2            [OI]6300_d      1.252      0.24     -33    26
# Comp:  2           [NII]6583_d      16.07      0.24     -33    26
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
