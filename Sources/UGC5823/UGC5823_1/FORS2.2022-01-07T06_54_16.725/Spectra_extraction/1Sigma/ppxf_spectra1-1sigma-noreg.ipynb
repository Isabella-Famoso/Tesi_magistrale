# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt") 
z = red[0][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18511937 2.18584583 2.18657229 ... 3.48184835 3.48257481 3.48330126]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3150, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314346256

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        14        46
# chi2/DOF: 0.05434; DOF: 1943; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        23         7
# chi2/DOF: 0.03840; DOF: 1903; degree = 4; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.87636797 1.73914108 1.5384458  ... 1.02718482 0.89633841 0.68453924]
# [1.20484187 1.22058921 1.22570388 ... 0.86179926 0.86420622 0.86132482]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([22.91206722,  7.44362463])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:         3        24
#  comp.  2:        -7        27
# chi2/DOF: 1.068; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.09      0.46       3    24
# Comp:  1                Halpha      55.54      0.46       3    24
# Comp:  2             [SII]6716      9.286      0.46      -7    27
# Comp:  2             [SII]6731      6.967      0.46      -7    27
# Comp:  2              HeII4687      0.000      0.46      -7    27
# Comp:  2               HeI5876      2.359      0.46      -7    27
# Comp:  2          [OIII]5007_d      29.95      0.58      -7    27
# Comp:  2            [OI]6300_d      1.301      0.58      -7    27
# Comp:  2           [NII]6583_d      12.45      0.58      -7    27
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  36.14; gas flux:     21 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  93.21; gas flux:     76 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   14.5; gas flux:     13 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   11.6; gas flux:     10 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.858; gas flux:      3 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  37.69; gas flux:     31 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.647; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  15.15; gas flux:     17 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        89        48
#  comp.  1:         6        36
#  comp.  2:        -5        13
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.03      0.47       6    36
# Comp:  1                Halpha      58.63      0.47       6    36
# Comp:  2             [SII]6716      9.090      0.45      -5    13
# Comp:  2             [SII]6731      7.055      0.45      -5    13
# Comp:  2              HeII4687      0.000      0.45      -5    13
# Comp:  2               HeI5876      2.264      0.45      -5    13
# Comp:  2          [OIII]5007_d      28.76      0.56      -5    13
# Comp:  2            [OI]6300_d     0.6528      0.56      -5    13
# Comp:  2           [NII]6583_d      11.64      0.56      -5    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:         3        23
#  comp.  2:        -5        25
# chi2/DOF: 1.053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.90      0.45       3    23
# Comp:  1                Halpha      55.11      0.45       3    23
# Comp:  2             [SII]6716      9.590      0.46      -5    25
# Comp:  2             [SII]6731      6.901      0.46      -5    25
# Comp:  2              HeII4687      0.000      0.46      -5    25
# Comp:  2               HeI5876      2.600      0.46      -5    25
# Comp:  2          [OIII]5007_d      29.42      0.58      -5    25
# Comp:  2            [OI]6300_d      1.589      0.58      -5    25
# Comp:  2           [NII]6583_d      11.74      0.58      -5    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88         1
#  comp.  1:         4        22
#  comp.  2:        -4        34
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.33      0.45       4    22
# Comp:  1                Halpha      55.95      0.45       4    22
# Comp:  2             [SII]6716      8.679      0.47      -4    34
# Comp:  2             [SII]6731      7.513      0.47      -4    34
# Comp:  2              HeII4687      0.000      0.47      -4    34
# Comp:  2               HeI5876      2.278      0.47      -4    34
# Comp:  2          [OIII]5007_d      28.73      0.59      -4    34
# Comp:  2            [OI]6300_d      1.518      0.59      -4    34
# Comp:  2           [NII]6583_d      12.23      0.59      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45        23
#  comp.  1:         4        24
#  comp.  2:        -9        23
# chi2/DOF: 1.053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.73      0.46       4    24
# Comp:  1                Halpha      55.31      0.46       4    24
# Comp:  2             [SII]6716      9.771      0.45      -9    23
# Comp:  2             [SII]6731      6.930      0.45      -9    23
# Comp:  2              HeII4687     0.2058      0.45      -9    23
# Comp:  2               HeI5876      2.471      0.45      -9    23
# Comp:  2          [OIII]5007_d      28.12      0.57      -9    23
# Comp:  2            [OI]6300_d     0.8968      0.57      -9    23
# Comp:  2           [NII]6583_d      11.83      0.57      -9    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        45
#  comp.  1:        -0        17
#  comp.  2:        -9        23
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.29      0.45      -0    17
# Comp:  1                Halpha      53.46      0.45      -0    17
# Comp:  2             [SII]6716      9.357      0.45      -9    23
# Comp:  2             [SII]6731      6.687      0.45      -9    23
# Comp:  2              HeII4687      0.000      0.45      -9    23
# Comp:  2               HeI5876      2.123      0.45      -9    23
# Comp:  2          [OIII]5007_d      31.40      0.57      -9    23
# Comp:  2            [OI]6300_d      1.775      0.57      -9    23
# Comp:  2           [NII]6583_d      12.29      0.57      -9    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        39
#  comp.  1:         4        18
#  comp.  2:        -3        34
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.29      0.45       4    18
# Comp:  1                Halpha      55.31      0.45       4    18
# Comp:  2             [SII]6716      9.127      0.47      -3    34
# Comp:  2             [SII]6731      7.198      0.47      -3    34
# Comp:  2              HeII4687      0.000      0.47      -3    34
# Comp:  2               HeI5876      2.670      0.47      -3    34
# Comp:  2          [OIII]5007_d      28.66      0.59      -3    34
# Comp:  2            [OI]6300_d      1.424      0.59      -3    34
# Comp:  2           [NII]6583_d      14.00      0.59      -3    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:         8        32
#  comp.  2:       -14        23
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.44      0.46       8    32
# Comp:  1                Halpha      57.49      0.46       8    32
# Comp:  2             [SII]6716      9.429      0.45     -14    23
# Comp:  2             [SII]6731      7.182      0.45     -14    23
# Comp:  2              HeII4687    0.04759      0.45     -14    23
# Comp:  2               HeI5876      2.298      0.45     -14    23
# Comp:  2          [OIII]5007_d      29.77      0.57     -14    23
# Comp:  2            [OI]6300_d      1.462      0.57     -14    23
# Comp:  2           [NII]6583_d      10.88      0.57     -14    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        83        27
#  comp.  1:        -1        15
#  comp.  2:        -4        40
# chi2/DOF: 1.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.75      0.45      -1    15
# Comp:  1                Halpha      53.23      0.45      -1    15
# Comp:  2             [SII]6716      10.04      0.48      -4    40
# Comp:  2             [SII]6731      7.425      0.48      -4    40
# Comp:  2              HeII4687    0.06655      0.48      -4    40
# Comp:  2               HeI5876      2.580      0.48      -4    40
# Comp:  2          [OIII]5007_d      29.59      0.60      -4    40
# Comp:  2            [OI]6300_d      1.760      0.60      -4    40
# Comp:  2           [NII]6583_d      13.22      0.60      -4    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        62        33
#  comp.  1:         4        23
#  comp.  2:        -7        29
# chi2/DOF: 1.056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.22      0.45       4    23
# Comp:  1                Halpha      55.06      0.45       4    23
# Comp:  2             [SII]6716      9.752      0.46      -7    29
# Comp:  2             [SII]6731      6.849      0.46      -7    29
# Comp:  2              HeII4687     0.4982      0.46      -7    29
# Comp:  2               HeI5876      2.344      0.46      -7    29
# Comp:  2          [OIII]5007_d      30.35      0.58      -7    29
# Comp:  2            [OI]6300_d      1.488      0.58      -7    29
# Comp:  2           [NII]6583_d      12.50      0.58      -7    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        81         1
#  comp.  1:         7        32
#  comp.  2:        -6        28
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.25      0.47       7    32
# Comp:  1                Halpha      57.77      0.47       7    32
# Comp:  2             [SII]6716      9.264      0.46      -6    28
# Comp:  2             [SII]6731      7.039      0.46      -6    28
# Comp:  2              HeII4687      0.000      0.46      -6    28
# Comp:  2               HeI5876      2.717      0.46      -6    28
# Comp:  2          [OIII]5007_d      29.51      0.58      -6    28
# Comp:  2            [OI]6300_d      1.415      0.58      -6    28
# Comp:  2           [NII]6583_d      11.15      0.58      -6    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22         1
#  comp.  1:        -1         1
#  comp.  2:        -8        12
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.18      0.44      -1     1
# Comp:  1                Halpha      53.75      0.44      -1     1
# Comp:  2             [SII]6716      9.536      0.45      -8    12
# Comp:  2             [SII]6731      6.865      0.45      -8    12
# Comp:  2              HeII4687     0.3574      0.45      -8    12
# Comp:  2               HeI5876      2.385      0.45      -8    12
# Comp:  2          [OIII]5007_d      28.40      0.56      -8    12
# Comp:  2            [OI]6300_d      1.708      0.56      -8    12
# Comp:  2           [NII]6583_d      13.57      0.56      -8    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        10
#  comp.  1:         5        37
#  comp.  2:       -11        27
# chi2/DOF: 1.006; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.54      0.47       5    37
# Comp:  1                Halpha      59.21      0.47       5    37
# Comp:  2             [SII]6716      8.963      0.46     -11    27
# Comp:  2             [SII]6731      7.054      0.46     -11    27
# Comp:  2              HeII4687      0.000      0.46     -11    27
# Comp:  2               HeI5876      2.922      0.46     -11    27
# Comp:  2          [OIII]5007_d      27.65      0.58     -11    27
# Comp:  2            [OI]6300_d      1.039      0.58     -11    27
# Comp:  2           [NII]6583_d      12.36      0.58     -11    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        62        24
#  comp.  1:         5        23
#  comp.  2:       -13        27
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.69      0.45       5    23
# Comp:  1                Halpha      55.96      0.45       5    23
# Comp:  2             [SII]6716      9.466      0.46     -13    27
# Comp:  2             [SII]6731      7.298      0.46     -13    27
# Comp:  2              HeII4687      0.000      0.46     -13    27
# Comp:  2               HeI5876      2.526      0.46     -13    27
# Comp:  2          [OIII]5007_d      30.63      0.58     -13    27
# Comp:  2            [OI]6300_d      1.082      0.58     -13    27
# Comp:  2           [NII]6583_d      12.30      0.58     -13    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56         1
#  comp.  1:         6        36
#  comp.  2:        -8        34
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.02      0.47       6    36
# Comp:  1                Halpha      58.46      0.47       6    36
# Comp:  2             [SII]6716      9.616      0.47      -8    34
# Comp:  2             [SII]6731      6.882      0.47      -8    34
# Comp:  2              HeII4687      0.000      0.47      -8    34
# Comp:  2               HeI5876      2.611      0.47      -8    34
# Comp:  2          [OIII]5007_d      30.99      0.59      -8    34
# Comp:  2            [OI]6300_d      1.307      0.59      -8    34
# Comp:  2           [NII]6583_d      12.26      0.59      -8    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        62         1
#  comp.  1:         1         1
#  comp.  2:        -8        26
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.81      0.44       1     1
# Comp:  1                Halpha      52.74      0.44       1     1
# Comp:  2             [SII]6716      9.603      0.46      -8    26
# Comp:  2             [SII]6731      6.648      0.46      -8    26
# Comp:  2              HeII4687      0.000      0.46      -8    26
# Comp:  2               HeI5876      2.494      0.46      -8    26
# Comp:  2          [OIII]5007_d      31.08      0.58      -8    26
# Comp:  2            [OI]6300_d      1.535      0.58      -8    26
# Comp:  2           [NII]6583_d      13.12      0.58      -8    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61        76
#  comp.  1:         3        20
#  comp.  2:        -4        34
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.82      0.45       3    20
# Comp:  1                Halpha      56.08      0.45       3    20
# Comp:  2             [SII]6716      8.878      0.47      -4    34
# Comp:  2             [SII]6731      6.921      0.47      -4    34
# Comp:  2              HeII4687      0.000      0.47      -4    34
# Comp:  2               HeI5876      2.521      0.47      -4    34
# Comp:  2          [OIII]5007_d      32.34      0.59      -4    34
# Comp:  2            [OI]6300_d      1.237      0.59      -4    34
# Comp:  2           [NII]6583_d      12.65      0.59      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        40
#  comp.  1:        -1        18
#  comp.  2:        -8         1
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.78      0.45      -1    18
# Comp:  1                Halpha      53.83      0.45      -1    18
# Comp:  2             [SII]6716      9.411      0.44      -8     1
# Comp:  2             [SII]6731      6.689      0.44      -8     1
# Comp:  2              HeII4687     0.2517      0.44      -8     1
# Comp:  2               HeI5876      2.365      0.44      -8     1
# Comp:  2          [OIII]5007_d      27.80      0.56      -8     1
# Comp:  2            [OI]6300_d      1.239      0.56      -8     1
# Comp:  2           [NII]6583_d      12.58      0.56      -8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:         4        28
#  comp.  2:        -3        33
# chi2/DOF: 1.052; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.59      0.46       4    28
# Comp:  1                Halpha      55.22      0.46       4    28
# Comp:  2             [SII]6716      9.464      0.47      -3    33
# Comp:  2             [SII]6731      6.740      0.47      -3    33
# Comp:  2              HeII4687    0.01881      0.47      -3    33
# Comp:  2               HeI5876      2.739      0.47      -3    33
# Comp:  2          [OIII]5007_d      32.37      0.59      -3    33
# Comp:  2            [OI]6300_d     0.8727      0.59      -3    33
# Comp:  2           [NII]6583_d      12.44      0.59      -3    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:         2        10
#  comp.  2:        -3         2
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.57      0.44       2    10
# Comp:  1                Halpha      53.14      0.44       2    10
# Comp:  2             [SII]6716      9.626      0.44      -3     2
# Comp:  2             [SII]6731      6.666      0.44      -3     2
# Comp:  2              HeII4687      0.000      0.44      -3     2
# Comp:  2               HeI5876      2.108      0.44      -3     2
# Comp:  2          [OIII]5007_d      29.87      0.56      -3     2
# Comp:  2            [OI]6300_d      1.798      0.56      -3     2
# Comp:  2           [NII]6583_d      11.94      0.56      -3     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        99        54
#  comp.  1:         1        13
#  comp.  2:       -10        37
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.35      0.45       1    13
# Comp:  1                Halpha      53.08      0.45       1    13
# Comp:  2             [SII]6716      8.739      0.47     -10    37
# Comp:  2             [SII]6731      7.240      0.47     -10    37
# Comp:  2              HeII4687     0.2769      0.47     -10    37
# Comp:  2               HeI5876      1.924      0.47     -10    37
# Comp:  2          [OIII]5007_d      29.59      0.60     -10    37
# Comp:  2            [OI]6300_d      1.461      0.60     -10    37
# Comp:  2           [NII]6583_d      12.47      0.60     -10    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        87         1
#  comp.  1:         4        23
#  comp.  2:        -4        24
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.98      0.45       4    23
# Comp:  1                Halpha      55.40      0.45       4    23
# Comp:  2             [SII]6716      9.458      0.46      -4    24
# Comp:  2             [SII]6731      7.318      0.46      -4    24
# Comp:  2              HeII4687     0.4163      0.46      -4    24
# Comp:  2               HeI5876      2.537      0.46      -4    24
# Comp:  2          [OIII]5007_d      31.00      0.58      -4    24
# Comp:  2            [OI]6300_d      1.838      0.58      -4    24
# Comp:  2           [NII]6583_d      12.04      0.58      -4    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        33
#  comp.  1:         0        19
#  comp.  2:        -9        30
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.41      0.45       0    19
# Comp:  1                Halpha      53.24      0.45       0    19
# Comp:  2             [SII]6716      9.686      0.46      -9    30
# Comp:  2             [SII]6731      7.000      0.46      -9    30
# Comp:  2              HeII4687     0.1200      0.46      -9    30
# Comp:  2               HeI5876      2.562      0.46      -9    30
# Comp:  2          [OIII]5007_d      30.58      0.58      -9    30
# Comp:  2            [OI]6300_d      1.324      0.58      -9    30
# Comp:  2           [NII]6583_d      11.65      0.58      -9    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        80         1
#  comp.  1:         6        32
#  comp.  2:        -2        36
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.68      0.46       6    32
# Comp:  1                Halpha      58.27      0.46       6    32
# Comp:  2             [SII]6716      9.661      0.47      -2    36
# Comp:  2             [SII]6731      7.278      0.47      -2    36
# Comp:  2              HeII4687     0.3334      0.47      -2    36
# Comp:  2               HeI5876      2.218      0.47      -2    36
# Comp:  2          [OIII]5007_d      31.09      0.59      -2    36
# Comp:  2            [OI]6300_d      1.252      0.59      -2    36
# Comp:  2           [NII]6583_d      13.45      0.59      -2    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46        35
#  comp.  1:         3        24
#  comp.  2:       -10        22
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.06      0.46       3    24
# Comp:  1                Halpha      56.61      0.46       3    24
# Comp:  2             [SII]6716      9.596      0.45     -10    22
# Comp:  2             [SII]6731      6.850      0.45     -10    22
# Comp:  2              HeII4687     0.4998      0.45     -10    22
# Comp:  2               HeI5876      2.448      0.45     -10    22
# Comp:  2          [OIII]5007_d      31.36      0.57     -10    22
# Comp:  2            [OI]6300_d      1.608      0.57     -10    22
# Comp:  2           [NII]6583_d      11.63      0.57     -10    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        86
#  comp.  1:         6        33
#  comp.  2:        -5        46
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.91      0.47       6    33
# Comp:  1                Halpha      57.76      0.47       6    33
# Comp:  2             [SII]6716      10.70      0.49      -5    46
# Comp:  2             [SII]6731      7.043      0.49      -5    46
# Comp:  2              HeII4687      0.000      0.49      -5    46
# Comp:  2               HeI5876      2.581      0.49      -5    46
# Comp:  2          [OIII]5007_d      32.94      0.61      -5    46
# Comp:  2            [OI]6300_d     0.8928      0.61      -5    46
# Comp:  2           [NII]6583_d      14.34      0.61      -5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58        40
#  comp.  1:        -0         1
#  comp.  2:        -6        33
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.65      0.44      -0     1
# Comp:  1                Halpha      53.38      0.44      -0     1
# Comp:  2             [SII]6716      8.728      0.47      -6    33
# Comp:  2             [SII]6731      6.903      0.47      -6    33
# Comp:  2              HeII4687     0.6800      0.47      -6    33
# Comp:  2               HeI5876      2.529      0.47      -6    33
# Comp:  2          [OIII]5007_d      33.28      0.59      -6    33
# Comp:  2            [OI]6300_d      1.429      0.59      -6    33
# Comp:  2           [NII]6583_d      12.57      0.59      -6    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55         1
#  comp.  1:        -1        18
#  comp.  2:       -10        32
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.43      0.45      -1    18
# Comp:  1                Halpha      54.38      0.45      -1    18
# Comp:  2             [SII]6716      9.436      0.47     -10    32
# Comp:  2             [SII]6731      6.922      0.47     -10    32
# Comp:  2              HeII4687     0.3185      0.47     -10    32
# Comp:  2               HeI5876      2.491      0.47     -10    32
# Comp:  2          [OIII]5007_d      31.39      0.59     -10    32
# Comp:  2            [OI]6300_d      1.390      0.59     -10    32
# Comp:  2           [NII]6583_d      12.00      0.59     -10    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:         4        21
#  comp.  2:       -10        14
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.17      0.45       4    21
# Comp:  1                Halpha      56.12      0.45       4    21
# Comp:  2             [SII]6716      9.286      0.45     -10    14
# Comp:  2             [SII]6731      7.039      0.45     -10    14
# Comp:  2              HeII4687      0.000      0.45     -10    14
# Comp:  2               HeI5876      2.177      0.45     -10    14
# Comp:  2          [OIII]5007_d      28.37      0.56     -10    14
# Comp:  2            [OI]6300_d      1.451      0.56     -10    14
# Comp:  2           [NII]6583_d      12.19      0.56     -10    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69         1
#  comp.  1:         4        22
#  comp.  2:        -4        33
# chi2/DOF: 1.051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.80      0.45       4    22
# Comp:  1                Halpha      56.13      0.45       4    22
# Comp:  2             [SII]6716      9.095      0.47      -4    33
# Comp:  2             [SII]6731      6.995      0.47      -4    33
# Comp:  2              HeII4687      0.000      0.47      -4    33
# Comp:  2               HeI5876      2.399      0.47      -4    33
# Comp:  2          [OIII]5007_d      28.84      0.59      -4    33
# Comp:  2            [OI]6300_d      1.563      0.59      -4    33
# Comp:  2           [NII]6583_d      13.78      0.59      -4    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        19
#  comp.  1:         1         4
#  comp.  2:        -9        10
# chi2/DOF: 1.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.49      0.44       1     4
# Comp:  1                Halpha      52.84      0.44       1     4
# Comp:  2             [SII]6716      8.720      0.44      -9    10
# Comp:  2             [SII]6731      6.791      0.44      -9    10
# Comp:  2              HeII4687      0.000      0.44      -9    10
# Comp:  2               HeI5876      2.461      0.44      -9    10
# Comp:  2          [OIII]5007_d      30.86      0.56      -9    10
# Comp:  2            [OI]6300_d      1.172      0.56      -9    10
# Comp:  2           [NII]6583_d      11.90      0.56      -9    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67         1
#  comp.  1:         5        35
#  comp.  2:        -7        30
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.31      0.47       5    35
# Comp:  1                Halpha      57.67      0.47       5    35
# Comp:  2             [SII]6716      9.149      0.46      -7    30
# Comp:  2             [SII]6731      7.451      0.46      -7    30
# Comp:  2              HeII4687      0.000      0.46      -7    30
# Comp:  2               HeI5876      2.124      0.46      -7    30
# Comp:  2          [OIII]5007_d      29.79      0.58      -7    30
# Comp:  2            [OI]6300_d      1.093      0.58      -7    30
# Comp:  2           [NII]6583_d      12.53      0.58      -7    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69        87
#  comp.  1:         4        20
#  comp.  2:        -1        26
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.33      0.45       4    20
# Comp:  1                Halpha      55.13      0.45       4    20
# Comp:  2             [SII]6716      9.069      0.46      -1    26
# Comp:  2             [SII]6731      7.102      0.46      -1    26
# Comp:  2              HeII4687     0.3723      0.46      -1    26
# Comp:  2               HeI5876      2.229      0.46      -1    26
# Comp:  2          [OIII]5007_d      31.69      0.58      -1    26
# Comp:  2            [OI]6300_d     0.9570      0.58      -1    26
# Comp:  2           [NII]6583_d      12.39      0.58      -1    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        43
#  comp.  1:         5        18
#  comp.  2:        -2        29
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.96      0.45       5    18
# Comp:  1                Halpha      54.94      0.45       5    18
# Comp:  2             [SII]6716      9.193      0.46      -2    29
# Comp:  2             [SII]6731      6.654      0.46      -2    29
# Comp:  2              HeII4687    0.08535      0.46      -2    29
# Comp:  2               HeI5876      2.271      0.46      -2    29
# Comp:  2          [OIII]5007_d      32.52      0.58      -2    29
# Comp:  2            [OI]6300_d      1.269      0.58      -2    29
# Comp:  2           [NII]6583_d      12.04      0.58      -2    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:         0         1
#  comp.  2:         1        28
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.03      0.44       0     1
# Comp:  1                Halpha      53.16      0.44       0     1
# Comp:  2             [SII]6716      10.07      0.46       1    28
# Comp:  2             [SII]6731      6.930      0.46       1    28
# Comp:  2              HeII4687      0.000      0.46       1    28
# Comp:  2               HeI5876      2.732      0.46       1    28
# Comp:  2          [OIII]5007_d      29.95      0.58       1    28
# Comp:  2            [OI]6300_d      1.034      0.58       1    28
# Comp:  2           [NII]6583_d      10.93      0.58       1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:         1        12
#  comp.  2:        -8        26
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.00      0.45       1    12
# Comp:  1                Halpha      52.90      0.45       1    12
# Comp:  2             [SII]6716      8.864      0.46      -8    26
# Comp:  2             [SII]6731      6.598      0.46      -8    26
# Comp:  2              HeII4687     0.1893      0.46      -8    26
# Comp:  2               HeI5876      2.617      0.46      -8    26
# Comp:  2          [OIII]5007_d      29.41      0.58      -8    26
# Comp:  2            [OI]6300_d      1.081      0.58      -8    26
# Comp:  2           [NII]6583_d      11.91      0.58      -8    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        81         1
#  comp.  1:         2        31
#  comp.  2:        -7        21
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.16      0.46       2    31
# Comp:  1                Halpha      55.85      0.46       2    31
# Comp:  2             [SII]6716      9.798      0.45      -7    21
# Comp:  2             [SII]6731      7.114      0.45      -7    21
# Comp:  2              HeII4687     0.2402      0.45      -7    21
# Comp:  2               HeI5876      2.534      0.45      -7    21
# Comp:  2          [OIII]5007_d      30.87      0.57      -7    21
# Comp:  2            [OI]6300_d      1.812      0.57      -7    21
# Comp:  2           [NII]6583_d      13.09      0.57      -7    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:         0        27
#  comp.  2:        -4        18
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.13      0.46       0    27
# Comp:  1                Halpha      55.86      0.46       0    27
# Comp:  2             [SII]6716      8.662      0.45      -4    18
# Comp:  2             [SII]6731      6.526      0.45      -4    18
# Comp:  2              HeII4687     0.2864      0.45      -4    18
# Comp:  2               HeI5876      1.913      0.45      -4    18
# Comp:  2          [OIII]5007_d      30.75      0.57      -4    18
# Comp:  2            [OI]6300_d      1.357      0.57      -4    18
# Comp:  2           [NII]6583_d      13.02      0.57      -4    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        26
#  comp.  1:         1         1
#  comp.  2:        -5        40
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.62      0.44       1     1
# Comp:  1                Halpha      52.88      0.44       1     1
# Comp:  2             [SII]6716      9.713      0.48      -5    40
# Comp:  2             [SII]6731      7.145      0.48      -5    40
# Comp:  2              HeII4687      0.000      0.48      -5    40
# Comp:  2               HeI5876      2.188      0.48      -5    40
# Comp:  2          [OIII]5007_d      32.39      0.60      -5    40
# Comp:  2            [OI]6300_d      1.605      0.60      -5    40
# Comp:  2           [NII]6583_d      12.27      0.60      -5    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:         1         1
#  comp.  2:        -2        25
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.86      0.44       1     1
# Comp:  1                Halpha      53.25      0.44       1     1
# Comp:  2             [SII]6716      9.417      0.46      -2    25
# Comp:  2             [SII]6731      6.849      0.46      -2    25
# Comp:  2              HeII4687      0.000      0.46      -2    25
# Comp:  2               HeI5876      2.482      0.46      -2    25
# Comp:  2          [OIII]5007_d      29.39      0.58      -2    25
# Comp:  2            [OI]6300_d     0.8285      0.58      -2    25
# Comp:  2           [NII]6583_d      12.04      0.58      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:         2        27
#  comp.  2:        -6        38
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.69      0.46       2    27
# Comp:  1                Halpha      55.08      0.46       2    27
# Comp:  2             [SII]6716      9.311      0.47      -6    38
# Comp:  2             [SII]6731      6.936      0.47      -6    38
# Comp:  2              HeII4687      0.000      0.47      -6    38
# Comp:  2               HeI5876      2.280      0.47      -6    38
# Comp:  2          [OIII]5007_d      31.64      0.60      -6    38
# Comp:  2            [OI]6300_d     0.9651      0.60      -6    38
# Comp:  2           [NII]6583_d      12.15      0.60      -6    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:         6        35
#  comp.  2:        -1        31
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.31      0.47       6    35
# Comp:  1                Halpha      58.66      0.47       6    35
# Comp:  2             [SII]6716      9.695      0.46      -1    31
# Comp:  2             [SII]6731      6.905      0.46      -1    31
# Comp:  2              HeII4687     0.4499      0.46      -1    31
# Comp:  2               HeI5876      2.456      0.46      -1    31
# Comp:  2          [OIII]5007_d      28.55      0.59      -1    31
# Comp:  2            [OI]6300_d      1.087      0.59      -1    31
# Comp:  2           [NII]6583_d      12.43      0.59      -1    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88        38
#  comp.  1:         2        28
#  comp.  2:        -6        38
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.30      0.46       2    28
# Comp:  1                Halpha      56.99      0.46       2    28
# Comp:  2             [SII]6716      8.830      0.47      -6    38
# Comp:  2             [SII]6731      7.320      0.47      -6    38
# Comp:  2              HeII4687      0.000      0.47      -6    38
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.40      0.45       3    22
# Comp:  1                Halpha      55.13      0.45       3    22
# Comp:  2             [SII]6716      9.003      0.44      -6     9
# Comp:  2             [SII]6731      6.568      0.44      -6     9
# Comp:  2              HeII4687      0.000      0.44      -6     9
# Comp:  2               HeI5876      2.448      0.44      -6     9
# Comp:  2          [OIII]5007_d      30.64      0.56      -6     9
# Comp:  2            [OI]6300_d      1.303      0.56      -6     9
# Comp:  2           [NII]6583_d      11.54      0.56      -6     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
#  comp.  1:         4        35
#  comp.  2:        -1        27
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.85      0.47       4    35
# Comp:  1                Halpha      57.61      0.47       4    35
# Comp:  2             [SII]6716      9.184      0.46      -1    27
# Comp:  2             [SII]6731      6.813      0.46      -1    27
# Comp:  2              HeII4687      0.000      0.46      -1    27
# Comp:  2               HeI5876      2.154      0.46      -1    27
# Comp:  2          [OIII]5007_d      31.62      0.58      -1    27
# Comp:  2            [OI]6300_d      1.408      0.58      -1    27
# Comp:  2           [NII]6583_d      12.00      0.58      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        51         1
#  comp.  1:         0         8
#  comp.  2:        -7        37
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.66      0.44       0     8
# Comp:  1                Halpha      52.93      0.44       0     8
# Comp:  2             [SII]6716      9.448      0.47      -7    37
# Comp:  2             [SII]6731      7.395      0.47      -7    37
# Comp:  2              HeII4687      0.000      0.47      -7    37
# Comp:  2               HeI5876      2.889      0.47      -7    37
# Comp:  2          [OIII]5007_d      31.29      0.60      -7    37
# Comp:  2            [OI]6300_d      1.285      0.60      -7    37
# Comp:  2           [NII]6583_d      14.32      0.60      -7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90        53
#  comp.  1:        -1        15
#  comp.  2:       -13        19
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.39      0.45      -1    15
# Comp:  1                Halpha      53.43      0.45      -1    15
# Comp:  2             [SII]6716      8.900      0.45     -13    19
# Comp:  2             [SII]6731      7.108      0.45     -13    19
# Comp:  2              HeII4687     0.1552      0.45     -13    19
# Comp:  2               HeI5876      2.332      0.45     -13    19
# Comp:  2          [OIII]5007_d      27.66      0.57     -13    19
# Comp:  2            [OI]6300_d      1.236      0.57     -13    19
# Comp:  2           [NII]6583_d      12.34      0.57     -13    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       101        38
#  comp.  1:         4        18
#  comp.  2:       -11        13
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.20      0.45       4    18
# Comp:  1                Halpha      55.58      0.45       4    18
# Comp:  2             [SII]6716      9.356      0.45     -11    13
# Comp:  2             [SII]6731      6.796      0.45     -11    13
# Comp:  2              HeII4687      0.000      0.45     -11    13
# Comp:  2               HeI5876      1.971      0.45     -11    13
# Comp:  2          [OIII]5007_d      28.30      0.56     -11    13
# Comp:  2            [OI]6300_d      1.183      0.56     -11    13
# Comp:  2           [NII]6583_d      12.10      0.56     -11    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56         1
#  comp.  1:         2        25
#  comp.  2:        -7        18
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.94      0.46       2    25
# Comp:  1                Halpha      56.42      0.46       2    25
# Comp:  2             [SII]6716      9.127      0.45      -7    18
# Comp:  2             [SII]6731      7.026      0.45      -7    18
# Comp:  2              HeII4687      0.000      0.45      -7    18
# Comp:  2               HeI5876      2.346      0.45      -7    18
# Comp:  2          [OIII]5007_d      27.07      0.57      -7    18
# Comp:  2            [OI]6300_d     0.8283      0.57      -7    18
# Comp:  2           [NII]6583_d      12.46      0.57      -7    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        51        45
#  comp.  1:         1         9
#  comp.  2:        -1        27
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.08      0.44       1     9
# Comp:  1                Halpha      52.21      0.44       1     9
# Comp:  2             [SII]6716      8.568      0.46      -1    27
# Comp:  2             [SII]6731      7.046      0.46      -1    27
# Comp:  2              HeII4687      0.000      0.46      -1    27
# Comp:  2               HeI5876      2.267      0.46      -1    27
# Comp:  2          [OIII]5007_d      29.96      0.58      -1    27
# Comp:  2            [OI]6300_d     0.9204      0.58      -1    27
# Comp:  2           [NII]6583_d      12.58      0.58      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57        85
#  comp.  1:         6        33
#  comp.  2:       -12        26
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.66      0.47       6    33
# Comp:  1                Halpha      58.35      0.47       6    33
# Comp:  2             [SII]6716      9.498      0.46     -12    26
# Comp:  2             [SII]6731      6.799      0.46     -12    26
# Comp:  2              HeII4687      0.000      0.46     -12    26
# Comp:  2               HeI5876      2.699      0.46     -12    26
# Comp:  2          [OIII]5007_d      28.09      0.58     -12    26
# Comp:  2            [OI]6300_d      1.340      0.58     -12    26
# Comp:  2           [NII]6583_d      12.34      0.58     -12    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73        18
#  comp.  1:         3        28
#  comp.  2:        -4        41
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.57      0.46       3    28
# Comp:  1                Halpha      55.99      0.46       3    28
# Comp:  2             [SII]6716      9.706      0.48      -4    41
# Comp:  2             [SII]6731      7.555      0.48      -4    41
# Comp:  2              HeII4687      0.000      0.48      -4    41
# Comp:  2               HeI5876      2.241      0.48      -4    41
# Comp:  2          [OIII]5007_d      29.72      0.60      -4    41
# Comp:  2            [OI]6300_d      1.129      0.60      -4    41
# Comp:  2           [NII]6583_d      12.90      0.60      -4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:         2        32
#  comp.  2:        -4        25
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.64      0.47       2    32
# Comp:  1                Halpha      55.65      0.47       2    32
# Comp:  2             [SII]6716      9.338      0.46      -4    25
# Comp:  2             [SII]6731      7.019      0.46      -4    25
# Comp:  2              HeII4687      0.000      0.46      -4    25
# Comp:  2               HeI5876      1.852      0.46      -4    25
# Comp:  2          [OIII]5007_d      28.78      0.58      -4    25
# Comp:  2            [OI]6300_d      1.468      0.58      -4    25
# Comp:  2           [NII]6583_d      12.64      0.58      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:        -0        15
#  comp.  2:       -11         1
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.40      0.45      -0    15
# Comp:  1                Halpha      53.13      0.45      -0    15
# Comp:  2             [SII]6716      8.974      0.44     -11     1
# Comp:  2             [SII]6731      7.113      0.44     -11     1
# Comp:  2              HeII4687      0.000      0.44     -11     1
# Comp:  2               HeI5876      1.911      0.44     -11     1
# Comp:  2          [OIII]5007_d      28.52      0.56     -11     1
# Comp:  2            [OI]6300_d     0.8687      0.56     -11     1
# Comp:  2           [NII]6583_d      12.60      0.56     -11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45         1
#  comp.  1:         2        20
#  comp.  2:        -7         1
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      21.14      0.45       2    20
# Comp:  1                Halpha      55.99      0.45       2    20
# Comp:  2             [SII]6716      9.135      0.44      -7     1
# Comp:  2             [SII]6731      6.542      0.44      -7     1
# Comp:  2              HeII4687      0.000      0.44      -7     1
# Comp:  2               HeI5876      1.872      0.44      -7     1
# Comp:  2          [OIII]5007_d      28.09      0.56      -7     1
# Comp:  2            [OI]6300_d      1.461      0.56      -7     1
# Comp:  2           [NII]6583_d      11.53      0.56      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        38
#  comp.  1:        -2        16
#  comp.  2:       -11        24
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.09      0.45      -2    16
# Comp:  1                Halpha      53.60      0.45      -2    16
# Comp:  2             [SII]6716      8.866      0.46     -11    24
# Comp:  2             [SII]6731      6.556      0.46     -11    24
# Comp:  2              HeII4687     0.4005      0.46     -11    24
# Comp:  2               HeI5876      1.807      0.46     -11    24
# Comp:  2          [OIII]5007_d      27.30      0.57     -11    24
# Comp:  2            [OI]6300_d      1.737      0.57     -11    24
# Comp:  2           [NII]6583_d      11.55      0.57     -11    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73         1
#  comp.  1:         2        33
#  comp.  2:       -13        38
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.20      0.47       2    33
# Comp:  1                Halpha      55.76      0.47       2    33
# Comp:  2             [SII]6716      10.39      0.47     -13    38
# Comp:  2             [SII]6731      7.752      0.47     -13    38
# Comp:  2              HeII4687     0.3853      0.47     -13    38
# Comp:  2               HeI5876      2.495      0.47     -13    38
# Comp:  2          [OIII]5007_d      29.97      0.60     -13    38
# Comp:  2            [OI]6300_d      1.666      0.60     -13    38
# Comp:  2           [NII]6583_d      13.01      0.60     -13    38
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.03836565, 2.63315742, 0.66022095, 0.41520083, 0.19130018,
#        0.32789556, 1.58552746, 0.38885638, 0.94942948])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([21.38691854, 76.02634914, 13.00849376,  9.78145986,  0.        ,
#         2.89053892, 31.27718622,  1.71001209, 17.09313564])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum1s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum1s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum1s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.286747    0.013922
# 1        Halpha  1.019329    0.035304
# 2     [SII]6716  0.174412    0.008852
# 3     [SII]6731  0.131146    0.005567
# 4      HeII4687  0.000000    0.002565
# 5       HeI5876  0.038755    0.004396
# 6  [OIII]5007_d  0.419351    0.021258
# 7    [OI]6300_d  0.022927    0.005214
# 8   [NII]6583_d  0.229178    0.012730
#           Name      Flux  Error_flux
# 0        Hbeta  0.286747    0.013922
# 1       Halpha  1.019329    0.035304
# 2    [SII]6716  0.174412    0.008852
# 3    [SII]6731  0.131146    0.005567
# 4     HeII4687  0.000000    0.002565
# 5      HeI5876  0.038755    0.004396
# 6   [OIII]4959  0.104838    0.021258
# 7   [OIII]5007  0.314513    0.021258
# 8     [OI]6300  0.017195    0.005214
# 9     [OI]6364  0.005732    0.005214
# 10   [NII]6548  0.057294    0.012730
# 11   [NII]6583  0.171883    0.012730

# %%
np.median(flux_rf_rebin)
# Out:
# 0.013407576777265093
