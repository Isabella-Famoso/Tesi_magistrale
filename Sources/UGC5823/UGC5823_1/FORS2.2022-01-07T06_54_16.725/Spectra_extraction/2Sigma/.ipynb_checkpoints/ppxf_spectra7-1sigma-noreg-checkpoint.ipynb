# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_7.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt")
z = red[6][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_7']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.01857

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18526954 2.18599605 2.18672256 ... 3.48208763 3.48281414 3.48354065]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
# chi2/DOF: 0.01323; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
# chi2/DOF: 0.008983; DOF: 1912; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-20.02483367,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:        -3        20
#  comp.  2:        -8        29
# chi2/DOF: 1.377; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.95      0.29      -3    20
# Comp:  1                Halpha      171.4      0.29      -3    20
# Comp:  2             [SII]6716      25.83      0.30      -8    29
# Comp:  2             [SII]6731      18.78      0.30      -8    29
# Comp:  2              HeII4687     0.3303      0.30      -8    29
# Comp:  2               HeI5876      5.475      0.30      -8    29
# Comp:  2          [OIII]5007_d      86.56      0.38      -8    29
# Comp:  2            [OI]6300_d      3.581      0.38      -8    29
# Comp:  2           [NII]6583_d      36.81      0.38      -8    29
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  141.8; gas flux:     46 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  570.7; gas flux:    235 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  85.36; gas flux:     36 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  58.43; gas flux:     26 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.107; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  18.34; gas flux:      7 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  215.7; gas flux:     90 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  8.332; gas flux:      5 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  89.44; gas flux:     51 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        32        99
#  comp.  1:        -3        28
#  comp.  2:        -8        23
# chi2/DOF: 1.227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.37      0.30      -3    28
# Comp:  1                Halpha      172.5      0.30      -3    28
# Comp:  2             [SII]6716      25.53      0.29      -8    23
# Comp:  2             [SII]6731      19.16      0.29      -8    23
# Comp:  2              HeII4687     0.3289      0.29      -8    23
# Comp:  2               HeI5876      5.209      0.29      -8    23
# Comp:  2          [OIII]5007_d      84.45      0.37      -8    23
# Comp:  2            [OI]6300_d      2.680      0.37      -8    23
# Comp:  2           [NII]6583_d      35.95      0.37      -8    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        36
#  comp.  1:        -2        23
#  comp.  2:        -7        33
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.60      0.29      -2    23
# Comp:  1                Halpha      170.1      0.29      -2    23
# Comp:  2             [SII]6716      26.77      0.30      -7    33
# Comp:  2             [SII]6731      18.50      0.30      -7    33
# Comp:  2              HeII4687     0.3520      0.30      -7    33
# Comp:  2               HeI5876      5.937      0.30      -7    33
# Comp:  2          [OIII]5007_d      85.75      0.38      -7    33
# Comp:  2            [OI]6300_d      4.074      0.38      -7    33
# Comp:  2           [NII]6583_d      36.60      0.38      -7    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        82        51
#  comp.  1:        -3        19
#  comp.  2:        -6        31
# chi2/DOF: 1.204; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.18      0.29      -3    19
# Comp:  1                Halpha      171.2      0.29      -3    19
# Comp:  2             [SII]6716      24.96      0.30      -6    31
# Comp:  2             [SII]6731      19.63      0.30      -6    31
# Comp:  2              HeII4687     0.2957      0.30      -6    31
# Comp:  2               HeI5876      5.059      0.30      -6    31
# Comp:  2          [OIII]5007_d      81.46      0.38      -6    31
# Comp:  2            [OI]6300_d      3.916      0.38      -6    31
# Comp:  2           [NII]6583_d      36.33      0.38      -6    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        78         1
#  comp.  1:        -2        19
#  comp.  2:       -10        20
# chi2/DOF: 1.240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.42      0.29      -2    19
# Comp:  1                Halpha      169.3      0.29      -2    19
# Comp:  2             [SII]6716      25.63      0.29     -10    20
# Comp:  2             [SII]6731      18.70      0.29     -10    20
# Comp:  2              HeII4687     0.3546      0.29     -10    20
# Comp:  2               HeI5876      5.216      0.29     -10    20
# Comp:  2          [OIII]5007_d      81.95      0.37     -10    20
# Comp:  2            [OI]6300_d      3.009      0.37     -10    20
# Comp:  2           [NII]6583_d      35.24      0.37     -10    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88         1
#  comp.  1:        -3        21
#  comp.  2:        -9        25
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.39      0.29      -3    21
# Comp:  1                Halpha      169.2      0.29      -3    21
# Comp:  2             [SII]6716      26.16      0.29      -9    25
# Comp:  2             [SII]6731      18.00      0.29      -9    25
# Comp:  2              HeII4687     0.2953      0.29      -9    25
# Comp:  2               HeI5876      4.906      0.29      -9    25
# Comp:  2          [OIII]5007_d      90.15      0.37      -9    25
# Comp:  2            [OI]6300_d      3.916      0.37      -9    25
# Comp:  2           [NII]6583_d      36.83      0.37      -9    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        76
#  comp.  1:        -2        12
#  comp.  2:        -6        32
# chi2/DOF: 1.175; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.16      0.29      -2    12
# Comp:  1                Halpha      170.8      0.29      -2    12
# Comp:  2             [SII]6716      25.31      0.30      -6    32
# Comp:  2             [SII]6731      18.82      0.30      -6    32
# Comp:  2              HeII4687     0.3084      0.30      -6    32
# Comp:  2               HeI5876      5.832      0.30      -6    32
# Comp:  2          [OIII]5007_d      83.02      0.38      -6    32
# Comp:  2            [OI]6300_d      3.784      0.38      -6    32
# Comp:  2           [NII]6583_d      38.33      0.38      -6    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:        -1        20
#  comp.  2:       -13        27
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.25      0.29      -1    20
# Comp:  1                Halpha      170.7      0.29      -1    20
# Comp:  2             [SII]6716      25.78      0.30     -13    27
# Comp:  2             [SII]6731      19.48      0.30     -13    27
# Comp:  2              HeII4687     0.3939      0.30     -13    27
# Comp:  2               HeI5876      5.583      0.30     -13    27
# Comp:  2          [OIII]5007_d      88.28      0.37     -13    27
# Comp:  2            [OI]6300_d      3.899      0.37     -13    27
# Comp:  2           [NII]6583_d      35.73      0.37     -13    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        94         1
#  comp.  1:        -4        21
#  comp.  2:        -7        37
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.24      0.29      -4    21
# Comp:  1                Halpha      169.2      0.29      -4    21
# Comp:  2             [SII]6716      26.42      0.30      -7    37
# Comp:  2             [SII]6731      19.66      0.30      -7    37
# Comp:  2              HeII4687     0.3125      0.30      -7    37
# Comp:  2               HeI5876      5.669      0.30      -7    37
# Comp:  2          [OIII]5007_d      84.58      0.38      -7    37
# Comp:  2            [OI]6300_d      4.405      0.38      -7    37
# Comp:  2           [NII]6583_d      36.91      0.38      -7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       112        22
#  comp.  1:        -2        19
#  comp.  2:        -7        25
# chi2/DOF: 1.313; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.96      0.29      -2    19
# Comp:  1                Halpha      169.7      0.29      -2    19
# Comp:  2             [SII]6716      25.98      0.29      -7    25
# Comp:  2             [SII]6731      18.53      0.29      -7    25
# Comp:  2              HeII4687     0.3241      0.29      -7    25
# Comp:  2               HeI5876      5.560      0.29      -7    25
# Comp:  2          [OIII]5007_d      87.03      0.37      -7    25
# Comp:  2            [OI]6300_d      3.706      0.37      -7    25
# Comp:  2           [NII]6583_d      36.45      0.37      -7    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        34
#  comp.  1:        -3        23
#  comp.  2:        -8        32
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.35      0.29      -3    23
# Comp:  1                Halpha      170.8      0.29      -3    23
# Comp:  2             [SII]6716      26.28      0.30      -8    32
# Comp:  2             [SII]6731      19.18      0.30      -8    32
# Comp:  2              HeII4687     0.3698      0.30      -8    32
# Comp:  2               HeI5876      5.885      0.30      -8    32
# Comp:  2          [OIII]5007_d      84.73      0.38      -8    32
# Comp:  2            [OI]6300_d      3.533      0.38      -8    32
# Comp:  2           [NII]6583_d      36.49      0.38      -8    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46        72
#  comp.  1:        -4        15
#  comp.  2:        -6         6
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.25      0.29      -4    15
# Comp:  1                Halpha      170.5      0.29      -4    15
# Comp:  2             [SII]6716      24.95      0.29      -6     6
# Comp:  2             [SII]6731      17.86      0.29      -6     6
# Comp:  2              HeII4687     0.3085      0.29      -6     6
# Comp:  2               HeI5876      5.651      0.29      -6     6
# Comp:  2          [OIII]5007_d      80.99      0.36      -6     6
# Comp:  2            [OI]6300_d      3.947      0.36      -6     6
# Comp:  2           [NII]6583_d      36.20      0.36      -6     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         1
#  comp.  1:        -4        26
#  comp.  2:       -11        31
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.26      0.30      -4    26
# Comp:  1                Halpha      174.3      0.30      -4    26
# Comp:  2             [SII]6716      25.42      0.30     -11    31
# Comp:  2             [SII]6731      19.16      0.30     -11    31
# Comp:  2              HeII4687     0.3676      0.30     -11    31
# Comp:  2               HeI5876      6.286      0.30     -11    31
# Comp:  2          [OIII]5007_d      82.05      0.38     -11    31
# Comp:  2            [OI]6300_d      3.352      0.38     -11    31
# Comp:  2           [NII]6583_d      36.58      0.38     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        93
#  comp.  1:        -4        22
#  comp.  2:       -12        27
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.51      0.29      -4    22
# Comp:  1                Halpha      170.6      0.29      -4    22
# Comp:  2             [SII]6716      26.46      0.30     -12    27
# Comp:  2             [SII]6731      19.23      0.30     -12    27
# Comp:  2              HeII4687     0.2663      0.30     -12    27
# Comp:  2               HeI5876      5.550      0.30     -12    27
# Comp:  2          [OIII]5007_d      89.21      0.37     -12    27
# Comp:  2            [OI]6300_d      3.197      0.37     -12    27
# Comp:  2           [NII]6583_d      36.23      0.37     -12    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        75         1
#  comp.  1:        -3        26
#  comp.  2:        -8        24
# chi2/DOF: 1.234; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.41      0.29      -3    26
# Comp:  1                Halpha      170.5      0.29      -3    26
# Comp:  2             [SII]6716      26.23      0.29      -8    24
# Comp:  2             [SII]6731      18.63      0.29      -8    24
# Comp:  2              HeII4687     0.3898      0.29      -8    24
# Comp:  2               HeI5876      5.957      0.29      -8    24
# Comp:  2          [OIII]5007_d      88.20      0.37      -8    24
# Comp:  2            [OI]6300_d      3.241      0.37      -8    24
# Comp:  2           [NII]6583_d      36.12      0.37      -8    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:        -2        12
#  comp.  2:        -8        29
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.66      0.29      -2    12
# Comp:  1                Halpha      170.7      0.29      -2    12
# Comp:  2             [SII]6716      26.69      0.30      -8    29
# Comp:  2             [SII]6731      17.79      0.30      -8    29
# Comp:  2              HeII4687     0.3448      0.30      -8    29
# Comp:  2               HeI5876      5.744      0.30      -8    29
# Comp:  2          [OIII]5007_d      89.02      0.38      -8    29
# Comp:  2            [OI]6300_d      3.780      0.38      -8    29
# Comp:  2           [NII]6583_d      36.45      0.38      -8    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:        -3        16
#  comp.  2:        -7        38
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.95      0.29      -3    16
# Comp:  1                Halpha      169.5      0.29      -3    16
# Comp:  2             [SII]6716      26.14      0.31      -7    38
# Comp:  2             [SII]6731      18.72      0.31      -7    38
# Comp:  2              HeII4687     0.3502      0.31      -7    38
# Comp:  2               HeI5876      5.676      0.31      -7    38
# Comp:  2          [OIII]5007_d      92.81      0.39      -7    38
# Comp:  2            [OI]6300_d      3.512      0.39      -7    38
# Comp:  2           [NII]6583_d      38.12      0.39      -7    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88        43
#  comp.  1:        -3        18
#  comp.  2:        -7         1
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.64      0.29      -3    18
# Comp:  1                Halpha      171.7      0.29      -3    18
# Comp:  2             [SII]6716      25.26      0.28      -7     1
# Comp:  2             [SII]6731      18.22      0.28      -7     1
# Comp:  2              HeII4687     0.2978      0.28      -7     1
# Comp:  2               HeI5876      5.295      0.28      -7     1
# Comp:  2          [OIII]5007_d      81.85      0.36      -7     1
# Comp:  2            [OI]6300_d      3.503      0.36      -7     1
# Comp:  2           [NII]6583_d      36.13      0.36      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        -2        24
#  comp.  2:        -5        36
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.13      0.29      -2    24
# Comp:  1                Halpha      173.2      0.29      -2    24
# Comp:  2             [SII]6716      26.65      0.30      -5    36
# Comp:  2             [SII]6731      18.02      0.30      -5    36
# Comp:  2              HeII4687     0.3730      0.30      -5    36
# Comp:  2               HeI5876      5.938      0.30      -5    36
# Comp:  2          [OIII]5007_d      91.47      0.38      -5    36
# Comp:  2            [OI]6300_d      2.967      0.38      -5    36
# Comp:  2           [NII]6583_d      37.60      0.38      -5    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:        -3        21
#  comp.  2:        -3        12
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.92      0.29      -3    21
# Comp:  1                Halpha      169.4      0.29      -3    21
# Comp:  2             [SII]6716      25.86      0.29      -3    12
# Comp:  2             [SII]6731      17.98      0.29      -3    12
# Comp:  2              HeII4687     0.2737      0.29      -3    12
# Comp:  2               HeI5876      5.319      0.29      -3    12
# Comp:  2          [OIII]5007_d      85.16      0.36      -3    12
# Comp:  2            [OI]6300_d      4.152      0.36      -3    12
# Comp:  2           [NII]6583_d      34.53      0.36      -3    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:        -4        22
#  comp.  2:       -12        39
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.00      0.29      -4    22
# Comp:  1                Halpha      170.6      0.29      -4    22
# Comp:  2             [SII]6716      25.66      0.31     -12    39
# Comp:  2             [SII]6731      20.33      0.31     -12    39
# Comp:  2              HeII4687     0.3660      0.31     -12    39
# Comp:  2               HeI5876      4.980      0.31     -12    39
# Comp:  2          [OIII]5007_d      87.61      0.39     -12    39
# Comp:  2            [OI]6300_d      3.731      0.39     -12    39
# Comp:  2           [NII]6583_d      38.28      0.39     -12    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       118        36
#  comp.  1:        -3        21
#  comp.  2:        -8        34
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.59      0.29      -3    21
# Comp:  1                Halpha      168.9      0.29      -3    21
# Comp:  2             [SII]6716      26.09      0.30      -8    34
# Comp:  2             [SII]6731      19.88      0.30      -8    34
# Comp:  2              HeII4687     0.3015      0.30      -8    34
# Comp:  2               HeI5876      6.094      0.30      -8    34
# Comp:  2          [OIII]5007_d      91.19      0.38      -8    34
# Comp:  2            [OI]6300_d      4.526      0.38      -8    34
# Comp:  2           [NII]6583_d      37.09      0.38      -8    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        75         1
#  comp.  1:        -3        21
#  comp.  2:       -10        33
# chi2/DOF: 1.285; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.52      0.29      -3    21
# Comp:  1                Halpha      170.3      0.29      -3    21
# Comp:  2             [SII]6716      26.80      0.30     -10    33
# Comp:  2             [SII]6731      19.19      0.30     -10    33
# Comp:  2              HeII4687     0.3858      0.30     -10    33
# Comp:  2               HeI5876      5.630      0.30     -10    33
# Comp:  2          [OIII]5007_d      88.05      0.38     -10    33
# Comp:  2            [OI]6300_d      3.451      0.38     -10    33
# Comp:  2           [NII]6583_d      37.27      0.38     -10    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        68
#  comp.  1:        -4        21
#  comp.  2:        -7        40
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.96      0.29      -4    21
# Comp:  1                Halpha      172.7      0.29      -4    21
# Comp:  2             [SII]6716      27.25      0.31      -7    40
# Comp:  2             [SII]6731      19.64      0.31      -7    40
# Comp:  2              HeII4687     0.3911      0.31      -7    40
# Comp:  2               HeI5876      5.203      0.31      -7    40
# Comp:  2          [OIII]5007_d      89.58      0.39      -7    40
# Comp:  2            [OI]6300_d      3.514      0.39      -7    40
# Comp:  2           [NII]6583_d      38.11      0.39      -7    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        61
#  comp.  1:        -3        19
#  comp.  2:       -10        30
# chi2/DOF: 1.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.99      0.29      -3    19
# Comp:  1                Halpha      173.5      0.29      -3    19
# Comp:  2             [SII]6716      26.33      0.30     -10    30
# Comp:  2             [SII]6731      19.47      0.30     -10    30
# Comp:  2              HeII4687     0.3067      0.30     -10    30
# Comp:  2               HeI5876      5.600      0.30     -10    30
# Comp:  2          [OIII]5007_d      91.57      0.38     -10    30
# Comp:  2            [OI]6300_d      4.118      0.38     -10    30
# Comp:  2           [NII]6583_d      36.35      0.38     -10    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -2        22
#  comp.  2:        -9        43
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.89      0.29      -2    22
# Comp:  1                Halpha      171.1      0.29      -2    22
# Comp:  2             [SII]6716      28.37      0.31      -9    43
# Comp:  2             [SII]6731      19.21      0.31      -9    43
# Comp:  2              HeII4687     0.2100      0.31      -9    43
# Comp:  2               HeI5876      5.686      0.31      -9    43
# Comp:  2          [OIII]5007_d      93.92      0.39      -9    43
# Comp:  2            [OI]6300_d      3.294      0.39      -9    43
# Comp:  2           [NII]6583_d      39.50      0.39      -9    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        71        31
#  comp.  1:        -3        12
#  comp.  2:        -7        35
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.59      0.29      -3    12
# Comp:  1                Halpha      168.8      0.29      -3    12
# Comp:  2             [SII]6716      25.43      0.30      -7    35
# Comp:  2             [SII]6731      19.64      0.30      -7    35
# Comp:  2              HeII4687     0.3362      0.30      -7    35
# Comp:  2               HeI5876      6.075      0.30      -7    35
# Comp:  2          [OIII]5007_d      94.13      0.38      -7    35
# Comp:  2            [OI]6300_d      3.688      0.38      -7    35
# Comp:  2           [NII]6583_d      36.88      0.38      -7    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       100        16
#  comp.  1:        -5        21
#  comp.  2:       -11        30
# chi2/DOF: 1.130; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.95      0.29      -5    21
# Comp:  1                Halpha      172.5      0.29      -5    21
# Comp:  2             [SII]6716      26.07      0.30     -11    30
# Comp:  2             [SII]6731      17.88      0.30     -11    30
# Comp:  2              HeII4687     0.3433      0.30     -11    30
# Comp:  2               HeI5876      5.654      0.30     -11    30
# Comp:  2          [OIII]5007_d      91.09      0.38     -11    30
# Comp:  2            [OI]6300_d      3.919      0.38     -11    30
# Comp:  2           [NII]6583_d      36.67      0.38     -11    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        54
#  comp.  1:        -3        16
#  comp.  2:       -10        26
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.41      0.29      -3    16
# Comp:  1                Halpha      172.5      0.29      -3    16
# Comp:  2             [SII]6716      25.38      0.30     -10    26
# Comp:  2             [SII]6731      19.21      0.30     -10    26
# Comp:  2              HeII4687     0.3362      0.30     -10    26
# Comp:  2               HeI5876      5.121      0.30     -10    26
# Comp:  2          [OIII]5007_d      85.59      0.37     -10    26
# Comp:  2            [OI]6300_d      3.827      0.37     -10    26
# Comp:  2           [NII]6583_d      36.99      0.37     -10    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12       656
#  comp.  1:        -4        19
#  comp.  2:        -8        27
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.68      0.29      -4    19
# Comp:  1                Halpha      171.2      0.29      -4    19
# Comp:  2             [SII]6716      25.07      0.30      -8    27
# Comp:  2             [SII]6731      18.96      0.30      -8    27
# Comp:  2              HeII4687     0.3732      0.30      -8    27
# Comp:  2               HeI5876      5.640      0.30      -8    27
# Comp:  2          [OIII]5007_d      83.86      0.37      -8    27
# Comp:  2            [OI]6300_d      3.929      0.37      -8    27
# Comp:  2           [NII]6583_d      37.79      0.37      -8    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        86
#  comp.  1:        -1        15
#  comp.  2:        -7        16
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.36      0.29      -1    15
# Comp:  1                Halpha      168.9      0.29      -1    15
# Comp:  2             [SII]6716      25.41      0.29      -7    16
# Comp:  2             [SII]6731      18.78      0.29      -7    16
# Comp:  2              HeII4687     0.2770      0.29      -7    16
# Comp:  2               HeI5876      5.429      0.29      -7    16
# Comp:  2          [OIII]5007_d      87.92      0.36      -7    16
# Comp:  2            [OI]6300_d      3.220      0.36      -7    16
# Comp:  2           [NII]6583_d      36.82      0.36      -7    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        87         1
#  comp.  1:        -2        24
#  comp.  2:        -9        31
# chi2/DOF: 1.310; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.18      0.29      -2    24
# Comp:  1                Halpha      172.2      0.29      -2    24
# Comp:  2             [SII]6716      26.42      0.30      -9    31
# Comp:  2             [SII]6731      19.55      0.30      -9    31
# Comp:  2              HeII4687     0.3732      0.30      -9    31
# Comp:  2               HeI5876      5.178      0.30      -9    31
# Comp:  2          [OIII]5007_d      88.41      0.38      -9    31
# Comp:  2            [OI]6300_d      3.086      0.38      -9    31
# Comp:  2           [NII]6583_d      37.18      0.38      -9    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       110        73
#  comp.  1:        -2        18
#  comp.  2:        -4        25
# chi2/DOF: 0.9964; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.73      0.29      -2    18
# Comp:  1                Halpha      169.9      0.29      -2    18
# Comp:  2             [SII]6716      25.46      0.29      -4    25
# Comp:  2             [SII]6731      19.33      0.29      -4    25
# Comp:  2              HeII4687     0.3577      0.29      -4    25
# Comp:  2               HeI5876      5.348      0.29      -4    25
# Comp:  2          [OIII]5007_d      90.72      0.37      -4    25
# Comp:  2            [OI]6300_d      3.186      0.37      -4    25
# Comp:  2           [NII]6583_d      35.89      0.37      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        51
#  comp.  1:        -2        16
#  comp.  2:        -5        27
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.97      0.29      -2    16
# Comp:  1                Halpha      167.4      0.29      -2    16
# Comp:  2             [SII]6716      25.90      0.30      -5    27
# Comp:  2             [SII]6731      17.66      0.30      -5    27
# Comp:  2              HeII4687     0.2784      0.30      -5    27
# Comp:  2               HeI5876      5.403      0.30      -5    27
# Comp:  2          [OIII]5007_d      91.03      0.37      -5    27
# Comp:  2            [OI]6300_d      3.470      0.37      -5    27
# Comp:  2           [NII]6583_d      36.99      0.37      -5    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:        -2        12
#  comp.  2:        -3        32
# chi2/DOF: 1.099; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.78      0.29      -2    12
# Comp:  1                Halpha      170.5      0.29      -2    12
# Comp:  2             [SII]6716      27.34      0.30      -3    32
# Comp:  2             [SII]6731      18.93      0.30      -3    32
# Comp:  2              HeII4687     0.3014      0.30      -3    32
# Comp:  2               HeI5876      5.608      0.30      -3    32
# Comp:  2          [OIII]5007_d      84.82      0.38      -3    32
# Comp:  2            [OI]6300_d      3.410      0.38      -3    32
# Comp:  2           [NII]6583_d      35.88      0.38      -3    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        51
#  comp.  1:        -3        19
#  comp.  2:        -8        32
# chi2/DOF: 1.327; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.51      0.29      -3    19
# Comp:  1                Halpha      170.9      0.29      -3    19
# Comp:  2             [SII]6716      26.39      0.30      -8    32
# Comp:  2             [SII]6731      18.41      0.30      -8    32
# Comp:  2              HeII4687     0.2618      0.30      -8    32
# Comp:  2               HeI5876      6.157      0.30      -8    32
# Comp:  2          [OIII]5007_d      85.13      0.38      -8    32
# Comp:  2            [OI]6300_d      3.396      0.38      -8    32
# Comp:  2           [NII]6583_d      36.59      0.38      -8    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        51         1
#  comp.  1:        -2        23
#  comp.  2:        -7        22
# chi2/DOF: 1.237; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.33      0.29      -2    23
# Comp:  1                Halpha      173.4      0.29      -2    23
# Comp:  2             [SII]6716      26.54      0.29      -7    22
# Comp:  2             [SII]6731      19.45      0.29      -7    22
# Comp:  2              HeII4687     0.3548      0.29      -7    22
# Comp:  2               HeI5876      5.728      0.29      -7    22
# Comp:  2          [OIII]5007_d      88.17      0.37      -7    22
# Comp:  2            [OI]6300_d      4.253      0.37      -7    22
# Comp:  2           [NII]6583_d      37.00      0.37      -7    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        74         1
#  comp.  1:        -4        22
#  comp.  2:        -2        24
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.86      0.29      -4    22
# Comp:  1                Halpha      172.9      0.29      -4    22
# Comp:  2             [SII]6716      24.78      0.29      -2    24
# Comp:  2             [SII]6731      17.67      0.29      -2    24
# Comp:  2              HeII4687     0.3095      0.29      -2    24
# Comp:  2               HeI5876      4.811      0.29      -2    24
# Comp:  2          [OIII]5007_d      86.52      0.37      -2    24
# Comp:  2            [OI]6300_d      3.726      0.37      -2    24
# Comp:  2           [NII]6583_d      36.52      0.37      -2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88        78
#  comp.  1:        -3        19
#  comp.  2:        -9        41
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.70      0.29      -3    19
# Comp:  1                Halpha      168.3      0.29      -3    19
# Comp:  2             [SII]6716      26.89      0.31      -9    41
# Comp:  2             [SII]6731      19.22      0.31      -9    41
# Comp:  2              HeII4687     0.3056      0.31      -9    41
# Comp:  2               HeI5876      5.373      0.31      -9    41
# Comp:  2          [OIII]5007_d      92.65      0.39      -9    41
# Comp:  2            [OI]6300_d      3.939      0.39      -9    41
# Comp:  2           [NII]6583_d      38.83      0.39      -9    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        -3        14
#  comp.  2:        -3        30
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.87      0.29      -3    14
# Comp:  1                Halpha      169.0      0.29      -3    14
# Comp:  2             [SII]6716      26.51      0.30      -3    30
# Comp:  2             [SII]6731      18.37      0.30      -3    30
# Comp:  2              HeII4687     0.3572      0.30      -3    30
# Comp:  2               HeI5876      5.706      0.30      -3    30
# Comp:  2          [OIII]5007_d      84.49      0.38      -3    30
# Comp:  2            [OI]6300_d      3.203      0.38      -3    30
# Comp:  2           [NII]6583_d      36.62      0.38      -3    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54         1
#  comp.  1:        -3        22
#  comp.  2:        -9        39
# chi2/DOF: 1.211; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.51      0.29      -3    22
# Comp:  1                Halpha      169.0      0.29      -3    22
# Comp:  2             [SII]6716      26.85      0.31      -9    39
# Comp:  2             [SII]6731      18.89      0.31      -9    39
# Comp:  2              HeII4687     0.3894      0.31      -9    39
# Comp:  2               HeI5876      5.775      0.31      -9    39
# Comp:  2          [OIII]5007_d      91.73      0.39      -9    39
# Comp:  2            [OI]6300_d      3.345      0.39      -9    39
# Comp:  2           [NII]6583_d      37.73      0.39      -9    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:        -3        24
#  comp.  2:        -5        32
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.04      0.29      -3    24
# Comp:  1                Halpha      175.8      0.29      -3    24
# Comp:  2             [SII]6716      25.89      0.30      -5    32
# Comp:  2             [SII]6731      18.69      0.30      -5    32
# Comp:  2              HeII4687     0.3194      0.30      -5    32
# Comp:  2               HeI5876      5.880      0.30      -5    32
# Comp:  2          [OIII]5007_d      80.98      0.38      -5    32
# Comp:  2            [OI]6300_d      3.116      0.38      -5    32
# Comp:  2           [NII]6583_d      36.55      0.38      -5    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       125        26
#  comp.  1:        -4        21
#  comp.  2:        -7        35
# chi2/DOF: 0.9781; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.69      0.29      -4    21
# Comp:  1                Halpha      174.4      0.29      -4    21
# Comp:  2             [SII]6716      25.12      0.30      -7    35
# Comp:  2             [SII]6731      19.23      0.30      -7    35
# Comp:  2              HeII4687     0.3339      0.30      -7    35
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.37      0.29      -2    20
# Comp:  1                Halpha      168.4      0.29      -2    20
# Comp:  2             [SII]6716      24.99      0.29      -5    17
# Comp:  2             [SII]6731      18.36      0.29      -5    17
# Comp:  2              HeII4687     0.3534      0.29      -5    17
# Comp:  2               HeI5876      5.542      0.29      -5    17
# Comp:  2          [OIII]5007_d      87.28      0.36      -5    17
# Comp:  2            [OI]6300_d      3.260      0.36      -5    17
# Comp:  2           [NII]6583_d      35.72      0.36      -5    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        87         1
#  comp.  1:        -3        27
#  comp.  2:        -1        27
# chi2/DOF: 1.150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.96      0.30      -3    27
# Comp:  1                Halpha      174.7      0.30      -3    27
# Comp:  2             [SII]6716      25.56      0.30      -1    27
# Comp:  2             [SII]6731      18.61      0.30      -1    27
# Comp:  2              HeII4687     0.2428      0.30      -1    27
# Comp:  2               HeI5876      5.397      0.30      -1    27
# Comp:  2          [OIII]5007_d      87.73      0.37      -1    27
# Comp:  2            [OI]6300_d      3.839      0.37      -1    27
# Comp:  2           [NII]6583_d      36.33      0.37      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59        78
#  comp.  1:        -3        21
#  comp.  2:        -8        34
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.81      0.29      -3    21
# Comp:  1                Halpha      172.1      0.29      -3    21
# Comp:  2             [SII]6716      25.54      0.30      -8    34
# Comp:  2             [SII]6731      19.31      0.30      -8    34
# Comp:  2              HeII4687     0.2910      0.30      -8    34
# Comp:  2               HeI5876      6.244      0.30      -8    34
# Comp:  2          [OIII]5007_d      88.46      0.38      -8    34
# Comp:  2            [OI]6300_d      3.565      0.38      -8    34
# Comp:  2           [NII]6583_d      38.02      0.38      -8    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        98        26
#  comp.  1:        -4        21
#  comp.  2:       -10        16
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.51      0.29      -4    21
# Comp:  1                Halpha      170.0      0.29      -4    21
# Comp:  2             [SII]6716      25.31      0.29     -10    16
# Comp:  2             [SII]6731      18.91      0.29     -10    16
# Comp:  2              HeII4687     0.3352      0.29     -10    16
# Comp:  2               HeI5876      5.367      0.29     -10    16
# Comp:  2          [OIII]5007_d      80.82      0.36     -10    16
# Comp:  2            [OI]6300_d      3.272      0.36     -10    16
# Comp:  2           [NII]6583_d      35.30      0.36     -10    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        37
#  comp.  1:        -4        16
#  comp.  2:        -9        22
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.96      0.29      -4    16
# Comp:  1                Halpha      170.8      0.29      -4    16
# Comp:  2             [SII]6716      25.76      0.29      -9    22
# Comp:  2             [SII]6731      19.48      0.29      -9    22
# Comp:  2              HeII4687     0.3477      0.29      -9    22
# Comp:  2               HeI5876      4.827      0.29      -9    22
# Comp:  2          [OIII]5007_d      84.57      0.37      -9    22
# Comp:  2            [OI]6300_d      3.458      0.37      -9    22
# Comp:  2           [NII]6583_d      36.61      0.37      -9    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       136        19
#  comp.  1:        -3        19
#  comp.  2:        -8        17
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.44      0.29      -3    19
# Comp:  1                Halpha      172.3      0.29      -3    19
# Comp:  2             [SII]6716      24.97      0.29      -8    17
# Comp:  2             [SII]6731      18.76      0.29      -8    17
# Comp:  2              HeII4687     0.3468      0.29      -8    17
# Comp:  2               HeI5876      5.389      0.29      -8    17
# Comp:  2          [OIII]5007_d      79.14      0.37      -8    17
# Comp:  2            [OI]6300_d      2.889      0.37      -8    17
# Comp:  2           [NII]6583_d      36.29      0.37      -8    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13       121
#  comp.  1:        -2        18
#  comp.  2:        -2        31
# chi2/DOF: 1.219; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.56      0.29      -2    18
# Comp:  1                Halpha      169.4      0.29      -2    18
# Comp:  2             [SII]6716      25.05      0.30      -2    31
# Comp:  2             [SII]6731      19.15      0.30      -2    31
# Comp:  2              HeII4687     0.2082      0.30      -2    31
# Comp:  2               HeI5876      5.460      0.30      -2    31
# Comp:  2          [OIII]5007_d      84.43      0.38      -2    31
# Comp:  2            [OI]6300_d      3.189      0.38      -2    31
# Comp:  2           [NII]6583_d      37.27      0.38      -2    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        -3        22
#  comp.  2:       -14        29
# chi2/DOF: 1.160; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.52      0.29      -3    22
# Comp:  1                Halpha      175.6      0.29      -3    22
# Comp:  2             [SII]6716      26.64      0.30     -14    29
# Comp:  2             [SII]6731      18.65      0.30     -14    29
# Comp:  2              HeII4687     0.2244      0.30     -14    29
# Comp:  2               HeI5876      6.198      0.30     -14    29
# Comp:  2          [OIII]5007_d      85.21      0.38     -14    29
# Comp:  2            [OI]6300_d      3.781      0.38     -14    29
# Comp:  2           [NII]6583_d      37.09      0.38     -14    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65         1
#  comp.  1:        -3        23
#  comp.  2:        -8        41
# chi2/DOF: 1.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.84      0.29      -3    23
# Comp:  1                Halpha      172.7      0.29      -3    23
# Comp:  2             [SII]6716      26.75      0.31      -8    41
# Comp:  2             [SII]6731      20.33      0.31      -8    41
# Comp:  2              HeII4687     0.4001      0.31      -8    41
# Comp:  2               HeI5876      5.774      0.31      -8    41
# Comp:  2          [OIII]5007_d      85.45      0.39      -8    41
# Comp:  2            [OI]6300_d      3.286      0.39      -8    41
# Comp:  2           [NII]6583_d      38.00      0.39      -8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        89        53
#  comp.  1:        -3        27
#  comp.  2:        -5        24
# chi2/DOF: 1.211; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.20      0.30      -3    27
# Comp:  1                Halpha      174.1      0.30      -3    27
# Comp:  2             [SII]6716      26.02      0.29      -5    24
# Comp:  2             [SII]6731      18.88      0.29      -5    24
# Comp:  2              HeII4687     0.3506      0.29      -5    24
# Comp:  2               HeI5876      4.807      0.29      -5    24
# Comp:  2          [OIII]5007_d      82.06      0.37      -5    24
# Comp:  2            [OI]6300_d      3.824      0.37      -5    24
# Comp:  2           [NII]6583_d      35.49      0.37      -5    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       104        32
#  comp.  1:        -3        22
#  comp.  2:       -10         7
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.88      0.29      -3    22
# Comp:  1                Halpha      168.8      0.29      -3    22
# Comp:  2             [SII]6716      24.95      0.29     -10     7
# Comp:  2             [SII]6731      18.28      0.29     -10     7
# Comp:  2              HeII4687     0.2920      0.29     -10     7
# Comp:  2               HeI5876      4.856      0.29     -10     7
# Comp:  2          [OIII]5007_d      84.42      0.36     -10     7
# Comp:  2            [OI]6300_d      3.288      0.36     -10     7
# Comp:  2           [NII]6583_d      35.31      0.36     -10     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       109         1
#  comp.  1:        -4        15
#  comp.  2:        -6         1
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.34      0.29      -4    15
# Comp:  1                Halpha      169.3      0.29      -4    15
# Comp:  2             [SII]6716      24.30      0.28      -6     1
# Comp:  2             [SII]6731      17.49      0.28      -6     1
# Comp:  2              HeII4687     0.3134      0.28      -6     1
# Comp:  2               HeI5876      4.727      0.28      -6     1
# Comp:  2          [OIII]5007_d      82.14      0.36      -6     1
# Comp:  2            [OI]6300_d      3.540      0.36      -6     1
# Comp:  2           [NII]6583_d      34.98      0.36      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90         1
#  comp.  1:        -3        18
#  comp.  2:       -11        30
# chi2/DOF: 1.155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.71      0.29      -3    18
# Comp:  1                Halpha      172.1      0.29      -3    18
# Comp:  2             [SII]6716      25.32      0.30     -11    30
# Comp:  2             [SII]6731      18.48      0.30     -11    30
# Comp:  2              HeII4687     0.3463      0.30     -11    30
# Comp:  2               HeI5876      4.714      0.30     -11    30
# Comp:  2          [OIII]5007_d      81.38      0.38     -11    30
# Comp:  2            [OI]6300_d      4.302      0.38     -11    30
# Comp:  2           [NII]6583_d      35.97      0.38     -11    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52         1
#  comp.  1:        -3        27
#  comp.  2:       -14        33
# chi2/DOF: 1.096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.00      0.30      -3    27
# Comp:  1                Halpha      174.1      0.30      -3    27
# Comp:  2             [SII]6716      27.20      0.30     -14    33
# Comp:  2             [SII]6731      19.53      0.30     -14    33
# Comp:  2              HeII4687     0.3336      0.30     -14    33
# Comp:  2               HeI5876      5.591      0.30     -14    33
# Comp:  2          [OIII]5007_d      86.39      0.38     -14    33
# Comp:  2            [OI]6300_d      4.179      0.38     -14    33
# Comp:  2           [NII]6583_d      37.38      0.38     -14    33
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([3.1288212 , 2.71269724, 1.14867556, 1.01592881, 0.04377993,
#        0.50011759, 3.99516108, 0.50342216, 1.38659089])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 45.58008105, 234.61998341,  36.18876815,  26.36536461,
#          0.32285501,   6.70921939,  90.40058921,   4.7052975 ,
#         50.54698236])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_7_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_7_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_7_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_7_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_7_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta   2.212019    0.151843
# 1        Halpha  11.386199    0.131648
# 2     [SII]6716   1.756255    0.055746
# 3     [SII]6731   1.279521    0.049303
# 4      HeII4687   0.015668    0.002125
# 5       HeI5876   0.325601    0.024271
# 6  [OIII]5007_d   4.387176    0.193887
# 7    [OI]6300_d   0.228350    0.024431
# 8   [NII]6583_d   2.453065    0.067292
#           Name       Flux  Error_flux
# 0        Hbeta   2.212019    0.151843
# 1       Halpha  11.386199    0.131648
# 2    [SII]6716   1.756255    0.055746
# 3    [SII]6731   1.279521    0.049303
# 4     HeII4687   0.015668    0.002125
# 5      HeI5876   0.325601    0.024271
# 6   [OIII]4959   1.096794    0.193887
# 7   [OIII]5007   3.290382    0.193887
# 8     [OI]6300   0.171262    0.024431
# 9     [OI]6364   0.057087    0.024431
# 10   [NII]6548   0.613266    0.067292
# 11   [NII]6583   1.839798    0.067292

# %%
np.median(flux_rf_rebin)
# Out:
# 0.048530387011599924
