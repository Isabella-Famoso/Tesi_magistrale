# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_6.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt")
z = red[5][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_6']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.01858

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18524809 2.18597459 2.18670109 ... 3.48205345 3.48277995 3.48350645]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
# chi2/DOF: 0.007274; DOF: 1943; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        39         1
# chi2/DOF: 0.004052; DOF: 1913; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([38.6575562 ,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        -7        30
#  comp.  2:        -8        34
# chi2/DOF: 0.9120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.19      0.19      -7    30
# Comp:  1                Halpha      39.67      0.19      -7    30
# Comp:  2             [SII]6716      7.799      0.19      -8    34
# Comp:  2             [SII]6731      5.368      0.19      -8    34
# Comp:  2              HeII4687      0.000      0.19      -8    34
# Comp:  2               HeI5876      1.351      0.19      -8    34
# Comp:  2          [OIII]5007_d      13.79      0.24      -8    34
# Comp:  2            [OI]6300_d      1.206      0.24      -8    34
# Comp:  2           [NII]6583_d      10.43      0.24      -8    34
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  57.66; gas flux:     12 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    197; gas flux:     54 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  38.64; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  24.93; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   6.83; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  52.12; gas flux:     14 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.312; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   37.9; gas flux:     14 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        51        72
#  comp.  1:        -7        35
#  comp.  2:       -12        30
# chi2/DOF: 0.8799; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.98      0.19      -7    35
# Comp:  1                Halpha      40.14      0.19      -7    35
# Comp:  2             [SII]6716      7.735      0.19     -12    30
# Comp:  2             [SII]6731      5.441      0.19     -12    30
# Comp:  2              HeII4687     0.3505      0.19     -12    30
# Comp:  2               HeI5876      1.216      0.19     -12    30
# Comp:  2          [OIII]5007_d      13.52      0.24     -12    30
# Comp:  2            [OI]6300_d      1.053      0.24     -12    30
# Comp:  2           [NII]6583_d      10.15      0.24     -12    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20        33
#  comp.  1:        -5        33
#  comp.  2:        -9        32
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.10      0.19      -5    33
# Comp:  1                Halpha      39.70      0.19      -5    33
# Comp:  2             [SII]6716      7.756      0.19      -9    32
# Comp:  2             [SII]6731      5.313      0.19      -9    32
# Comp:  2              HeII4687    0.06250      0.19      -9    32
# Comp:  2               HeI5876      1.501      0.19      -9    32
# Comp:  2          [OIII]5007_d      13.21      0.24      -9    32
# Comp:  2            [OI]6300_d      1.204      0.24      -9    32
# Comp:  2           [NII]6583_d      10.46      0.24      -9    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35         1
#  comp.  1:        -8        29
#  comp.  2:        -5        37
# chi2/DOF: 0.8835; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.97      0.19      -8    29
# Comp:  1                Halpha      39.71      0.19      -8    29
# Comp:  2             [SII]6716      7.841      0.19      -5    37
# Comp:  2             [SII]6731      5.713      0.19      -5    37
# Comp:  2              HeII4687     0.4879      0.19      -5    37
# Comp:  2               HeI5876      1.160      0.19      -5    37
# Comp:  2          [OIII]5007_d      13.44      0.24      -5    37
# Comp:  2            [OI]6300_d      1.173      0.24      -5    37
# Comp:  2           [NII]6583_d      10.38      0.24      -5    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:        -6        27
#  comp.  2:        -9        26
# chi2/DOF: 0.8792; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.73      0.19      -6    27
# Comp:  1                Halpha      38.98      0.19      -6    27
# Comp:  2             [SII]6716      7.530      0.19      -9    26
# Comp:  2             [SII]6731      5.291      0.19      -9    26
# Comp:  2              HeII4687      0.000      0.19      -9    26
# Comp:  2               HeI5876      1.339      0.19      -9    26
# Comp:  2          [OIII]5007_d      13.53      0.23      -9    26
# Comp:  2            [OI]6300_d      1.111      0.23      -9    26
# Comp:  2           [NII]6583_d      9.952      0.23      -9    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57         1
#  comp.  1:        -7        28
#  comp.  2:        -9        29
# chi2/DOF: 0.8824; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.19      -7    28
# Comp:  1                Halpha      39.35      0.19      -7    28
# Comp:  2             [SII]6716      7.781      0.19      -9    29
# Comp:  2             [SII]6731      5.138      0.19      -9    29
# Comp:  2              HeII4687      0.000      0.19      -9    29
# Comp:  2               HeI5876      1.181      0.19      -9    29
# Comp:  2          [OIII]5007_d      13.93      0.24      -9    29
# Comp:  2            [OI]6300_d      1.228      0.24      -9    29
# Comp:  2           [NII]6583_d      10.60      0.24      -9    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65        51
#  comp.  1:        -7        24
#  comp.  2:        -5        42
# chi2/DOF: 0.8718; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.35      0.18      -7    24
# Comp:  1                Halpha      39.08      0.18      -7    24
# Comp:  2             [SII]6716      8.264      0.19      -5    42
# Comp:  2             [SII]6731      5.583      0.19      -5    42
# Comp:  2              HeII4687      0.000      0.19      -5    42
# Comp:  2               HeI5876      1.473      0.19      -5    42
# Comp:  2          [OIII]5007_d      13.88      0.25      -5    42
# Comp:  2            [OI]6300_d      1.331      0.25      -5    42
# Comp:  2           [NII]6583_d      10.96      0.25      -5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24         1
#  comp.  1:        -6        30
#  comp.  2:       -11        31
# chi2/DOF: 0.8993; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.38      0.19      -6    30
# Comp:  1                Halpha      39.55      0.19      -6    30
# Comp:  2             [SII]6716      7.386      0.19     -11    31
# Comp:  2             [SII]6731      5.459      0.19     -11    31
# Comp:  2              HeII4687      0.000      0.19     -11    31
# Comp:  2               HeI5876      1.320      0.19     -11    31
# Comp:  2          [OIII]5007_d      14.05      0.24     -11    31
# Comp:  2            [OI]6300_d      1.256      0.24     -11    31
# Comp:  2           [NII]6583_d      10.26      0.24     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52        39
#  comp.  1:        -7        29
#  comp.  2:        -4        44
# chi2/DOF: 0.8525; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.99      0.19      -7    29
# Comp:  1                Halpha      39.26      0.19      -7    29
# Comp:  2             [SII]6716      8.151      0.20      -4    44
# Comp:  2             [SII]6731      5.564      0.20      -4    44
# Comp:  2              HeII4687     0.5217      0.20      -4    44
# Comp:  2               HeI5876      1.342      0.20      -4    44
# Comp:  2          [OIII]5007_d      14.06      0.25      -4    44
# Comp:  2            [OI]6300_d      1.362      0.25      -4    44
# Comp:  2           [NII]6583_d      10.56      0.25      -4    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:        -6        26
#  comp.  2:        -5        39
# chi2/DOF: 0.8684; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.84      0.19      -6    26
# Comp:  1                Halpha      38.95      0.19      -6    26
# Comp:  2             [SII]6716      8.186      0.19      -5    39
# Comp:  2             [SII]6731      5.375      0.19      -5    39
# Comp:  2              HeII4687     0.2382      0.19      -5    39
# Comp:  2               HeI5876      1.360      0.19      -5    39
# Comp:  2          [OIII]5007_d      14.48      0.24      -5    39
# Comp:  2            [OI]6300_d      1.415      0.24      -5    39
# Comp:  2           [NII]6583_d      10.79      0.24      -5    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:        -6        35
#  comp.  2:       -10        29
# chi2/DOF: 0.8858; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.77      0.19      -6    35
# Comp:  1                Halpha      40.07      0.19      -6    35
# Comp:  2             [SII]6716      7.719      0.19     -10    29
# Comp:  2             [SII]6731      5.402      0.19     -10    29
# Comp:  2              HeII4687      0.000      0.19     -10    29
# Comp:  2               HeI5876      1.398      0.19     -10    29
# Comp:  2          [OIII]5007_d      12.85      0.24     -10    29
# Comp:  2            [OI]6300_d      1.112      0.24     -10    29
# Comp:  2           [NII]6583_d      10.34      0.24     -10    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        10
#  comp.  1:        -8        28
#  comp.  2:        -5        28
# chi2/DOF: 0.8698; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.60      0.19      -8    28
# Comp:  1                Halpha      39.64      0.19      -8    28
# Comp:  2             [SII]6716      7.552      0.19      -5    28
# Comp:  2             [SII]6731      5.109      0.19      -5    28
# Comp:  2              HeII4687     0.2150      0.19      -5    28
# Comp:  2               HeI5876      1.559      0.19      -5    28
# Comp:  2          [OIII]5007_d      13.02      0.24      -5    28
# Comp:  2            [OI]6300_d      1.226      0.24      -5    28
# Comp:  2           [NII]6583_d      10.28      0.24      -5    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:        -8        34
#  comp.  2:        -8        33
# chi2/DOF: 0.8741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.79      0.19      -8    34
# Comp:  1                Halpha      40.29      0.19      -8    34
# Comp:  2             [SII]6716      7.941      0.19      -8    33
# Comp:  2             [SII]6731      5.406      0.19      -8    33
# Comp:  2              HeII4687      0.000      0.19      -8    33
# Comp:  2               HeI5876      1.572      0.19      -8    33
# Comp:  2          [OIII]5007_d      13.17      0.24      -8    33
# Comp:  2            [OI]6300_d      1.136      0.24      -8    33
# Comp:  2           [NII]6583_d      10.41      0.24      -8    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:        -8        29
#  comp.  2:       -10        30
# chi2/DOF: 0.8860; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.13      0.19      -8    29
# Comp:  1                Halpha      39.46      0.19      -8    29
# Comp:  2             [SII]6716      7.772      0.19     -10    30
# Comp:  2             [SII]6731      5.406      0.19     -10    30
# Comp:  2              HeII4687     0.3472      0.19     -10    30
# Comp:  2               HeI5876      1.267      0.19     -10    30
# Comp:  2          [OIII]5007_d      14.20      0.24     -10    30
# Comp:  2            [OI]6300_d      1.058      0.24     -10    30
# Comp:  2           [NII]6583_d      10.33      0.24     -10    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:        -6        33
#  comp.  2:        -5        36
# chi2/DOF: 0.8675; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.51      0.19      -6    33
# Comp:  1                Halpha      39.93      0.19      -6    33
# Comp:  2             [SII]6716      7.943      0.19      -5    36
# Comp:  2             [SII]6731      5.428      0.19      -5    36
# Comp:  2              HeII4687      0.000      0.19      -5    36
# Comp:  2               HeI5876      1.534      0.19      -5    36
# Comp:  2          [OIII]5007_d      14.61      0.24      -5    36
# Comp:  2            [OI]6300_d      1.089      0.24      -5    36
# Comp:  2           [NII]6583_d      10.39      0.24      -5    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40        37
#  comp.  1:        -6        25
#  comp.  2:        -8        27
# chi2/DOF: 0.8514; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.75      0.19      -6    25
# Comp:  1                Halpha      39.26      0.19      -6    25
# Comp:  2             [SII]6716      7.488      0.19      -8    27
# Comp:  2             [SII]6731      5.033      0.19      -8    27
# Comp:  2              HeII4687      0.000      0.19      -8    27
# Comp:  2               HeI5876      1.433      0.19      -8    27
# Comp:  2          [OIII]5007_d      13.22      0.23      -8    27
# Comp:  2            [OI]6300_d      1.279      0.23      -8    27
# Comp:  2           [NII]6583_d      10.01      0.23      -8    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         5
#  comp.  1:        -6        27
#  comp.  2:        -9        39
# chi2/DOF: 0.8795; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.65      0.19      -6    27
# Comp:  1                Halpha      39.14      0.19      -6    27
# Comp:  2             [SII]6716      8.018      0.19      -9    39
# Comp:  2             [SII]6731      5.385      0.19      -9    39
# Comp:  2              HeII4687     0.5508      0.19      -9    39
# Comp:  2               HeI5876      1.357      0.19      -9    39
# Comp:  2          [OIII]5007_d      14.12      0.24      -9    39
# Comp:  2            [OI]6300_d      1.192      0.24      -9    39
# Comp:  2           [NII]6583_d      10.60      0.24      -9    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27        36
#  comp.  1:        -7        27
#  comp.  2:        -7        26
# chi2/DOF: 0.8776; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.28      0.19      -7    27
# Comp:  1                Halpha      39.35      0.19      -7    27
# Comp:  2             [SII]6716      7.940      0.19      -7    26
# Comp:  2             [SII]6731      5.335      0.19      -7    26
# Comp:  2              HeII4687    0.04618      0.19      -7    26
# Comp:  2               HeI5876      1.284      0.19      -7    26
# Comp:  2          [OIII]5007_d      13.24      0.23      -7    26
# Comp:  2            [OI]6300_d      1.275      0.23      -7    26
# Comp:  2           [NII]6583_d      10.48      0.23      -7    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         1
#  comp.  1:        -6        35
#  comp.  2:        -8        35
# chi2/DOF: 0.8675; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.71      0.19      -6    35
# Comp:  1                Halpha      40.35      0.19      -6    35
# Comp:  2             [SII]6716      7.770      0.19      -8    35
# Comp:  2             [SII]6731      5.047      0.19      -8    35
# Comp:  2              HeII4687      0.000      0.19      -8    35
# Comp:  2               HeI5876      1.438      0.19      -8    35
# Comp:  2          [OIII]5007_d      13.77      0.24      -8    35
# Comp:  2            [OI]6300_d      1.107      0.24      -8    35
# Comp:  2           [NII]6583_d      10.39      0.24      -8    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        38
#  comp.  1:        -7        30
#  comp.  2:        -5        25
# chi2/DOF: 0.8657; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.68      0.19      -7    30
# Comp:  1                Halpha      39.60      0.19      -7    30
# Comp:  2             [SII]6716      7.678      0.19      -5    25
# Comp:  2             [SII]6731      5.151      0.19      -5    25
# Comp:  2              HeII4687      0.000      0.19      -5    25
# Comp:  2               HeI5876      1.241      0.19      -5    25
# Comp:  2          [OIII]5007_d      13.15      0.23      -5    25
# Comp:  2            [OI]6300_d      1.250      0.23      -5    25
# Comp:  2           [NII]6583_d      9.796      0.23      -5    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24         1
#  comp.  1:        -8        31
#  comp.  2:       -10        40
# chi2/DOF: 0.8695; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.95      0.19      -8    31
# Comp:  1                Halpha      39.87      0.19      -8    31
# Comp:  2             [SII]6716      7.872      0.19     -10    40
# Comp:  2             [SII]6731      5.728      0.19     -10    40
# Comp:  2              HeII4687      0.000      0.19     -10    40
# Comp:  2               HeI5876      1.098      0.19     -10    40
# Comp:  2          [OIII]5007_d      14.40      0.24     -10    40
# Comp:  2            [OI]6300_d      1.262      0.24     -10    40
# Comp:  2           [NII]6583_d      10.78      0.24     -10    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69        29
#  comp.  1:        -7        28
#  comp.  2:        -9        39
# chi2/DOF: 0.8595; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.00      0.19      -7    28
# Comp:  1                Halpha      39.31      0.19      -7    28
# Comp:  2             [SII]6716      8.007      0.19      -9    39
# Comp:  2             [SII]6731      5.658      0.19      -9    39
# Comp:  2              HeII4687     0.1893      0.19      -9    39
# Comp:  2               HeI5876      1.604      0.19      -9    39
# Comp:  2          [OIII]5007_d      13.83      0.24      -9    39
# Comp:  2            [OI]6300_d      1.269      0.24      -9    39
# Comp:  2           [NII]6583_d      10.54      0.24      -9    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:        -7        28
#  comp.  2:       -12        29
# chi2/DOF: 0.8927; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.50      0.19      -7    28
# Comp:  1                Halpha      39.19      0.19      -7    28
# Comp:  2             [SII]6716      7.520      0.19     -12    29
# Comp:  2             [SII]6731      5.312      0.19     -12    29
# Comp:  2              HeII4687      0.000      0.19     -12    29
# Comp:  2               HeI5876      1.450      0.19     -12    29
# Comp:  2          [OIII]5007_d      13.63      0.24     -12    29
# Comp:  2            [OI]6300_d      1.184      0.24     -12    29
# Comp:  2           [NII]6583_d      10.42      0.24     -12    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        53
#  comp.  1:        -7        33
#  comp.  2:        -9        38
# chi2/DOF: 0.8952; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.85      0.19      -7    33
# Comp:  1                Halpha      40.34      0.19      -7    33
# Comp:  2             [SII]6716      7.772      0.19      -9    38
# Comp:  2             [SII]6731      5.587      0.19      -9    38
# Comp:  2              HeII4687      0.000      0.19      -9    38
# Comp:  2               HeI5876      1.174      0.19      -9    38
# Comp:  2          [OIII]5007_d      13.84      0.24      -9    38
# Comp:  2            [OI]6300_d      1.142      0.24      -9    38
# Comp:  2           [NII]6583_d      10.52      0.24      -9    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -8        28
#  comp.  2:       -12        34
# chi2/DOF: 0.8904; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.48      0.19      -8    28
# Comp:  1                Halpha      39.93      0.19      -8    28
# Comp:  2             [SII]6716      8.071      0.19     -12    34
# Comp:  2             [SII]6731      5.508      0.19     -12    34
# Comp:  2              HeII4687     0.1408      0.19     -12    34
# Comp:  2               HeI5876      1.462      0.19     -12    34
# Comp:  2          [OIII]5007_d      14.18      0.24     -12    34
# Comp:  2            [OI]6300_d      1.298      0.24     -12    34
# Comp:  2           [NII]6583_d      10.24      0.24     -12    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        -6        33
#  comp.  2:        -7        42
# chi2/DOF: 0.8808; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.70      0.19      -6    33
# Comp:  1                Halpha      39.66      0.19      -6    33
# Comp:  2             [SII]6716      8.025      0.19      -7    42
# Comp:  2             [SII]6731      5.361      0.19      -7    42
# Comp:  2              HeII4687     0.3339      0.19      -7    42
# Comp:  2               HeI5876      1.277      0.19      -7    42
# Comp:  2          [OIII]5007_d      14.68      0.25      -7    42
# Comp:  2            [OI]6300_d      1.096      0.25      -7    42
# Comp:  2           [NII]6583_d      10.88      0.25      -7    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -6        26
#  comp.  2:       -10        36
# chi2/DOF: 0.8839; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.16      0.19      -6    26
# Comp:  1                Halpha      39.38      0.19      -6    26
# Comp:  2             [SII]6716      7.769      0.19     -10    36
# Comp:  2             [SII]6731      5.539      0.19     -10    36
# Comp:  2              HeII4687     0.2238      0.19     -10    36
# Comp:  2               HeI5876      1.614      0.19     -10    36
# Comp:  2          [OIII]5007_d      14.53      0.24     -10    36
# Comp:  2            [OI]6300_d      1.117      0.24     -10    36
# Comp:  2           [NII]6583_d      10.27      0.24     -10    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        39
#  comp.  1:        -9        30
#  comp.  2:       -10        36
# chi2/DOF: 0.8729; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.20      0.19      -9    30
# Comp:  1                Halpha      40.27      0.19      -9    30
# Comp:  2             [SII]6716      7.789      0.19     -10    36
# Comp:  2             [SII]6731      5.170      0.19     -10    36
# Comp:  2              HeII4687     0.4482      0.19     -10    36
# Comp:  2               HeI5876      1.327      0.19     -10    36
# Comp:  2          [OIII]5007_d      14.78      0.24     -10    36
# Comp:  2            [OI]6300_d      1.254      0.24     -10    36
# Comp:  2           [NII]6583_d      10.45      0.24     -10    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25         1
#  comp.  1:        -8        27
#  comp.  2:        -9        37
# chi2/DOF: 0.8827; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.96      0.19      -8    27
# Comp:  1                Halpha      39.59      0.19      -8    27
# Comp:  2             [SII]6716      7.999      0.19      -9    37
# Comp:  2             [SII]6731      5.447      0.19      -9    37
# Comp:  2              HeII4687    0.06313      0.19      -9    37
# Comp:  2               HeI5876      1.272      0.19      -9    37
# Comp:  2          [OIII]5007_d      13.67      0.24      -9    37
# Comp:  2            [OI]6300_d      1.293      0.24      -9    37
# Comp:  2           [NII]6583_d      10.66      0.24      -9    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        53
#  comp.  1:        -8        29
#  comp.  2:        -6        38
# chi2/DOF: 0.8694; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.40      0.19      -8    29
# Comp:  1                Halpha      39.69      0.19      -8    29
# Comp:  2             [SII]6716      8.086      0.19      -6    38
# Comp:  2             [SII]6731      5.567      0.19      -6    38
# Comp:  2              HeII4687      0.000      0.19      -6    38
# Comp:  2               HeI5876      1.312      0.19      -6    38
# Comp:  2          [OIII]5007_d      14.28      0.24      -6    38
# Comp:  2            [OI]6300_d      1.340      0.24      -6    38
# Comp:  2           [NII]6583_d      10.73      0.24      -6    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        68
#  comp.  1:        -6        25
#  comp.  2:       -10        22
# chi2/DOF: 0.8630; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.35      0.19      -6    25
# Comp:  1                Halpha      39.09      0.19      -6    25
# Comp:  2             [SII]6716      7.433      0.18     -10    22
# Comp:  2             [SII]6731      5.411      0.18     -10    22
# Comp:  2              HeII4687     0.2630      0.18     -10    22
# Comp:  2               HeI5876      1.324      0.18     -10    22
# Comp:  2          [OIII]5007_d      13.54      0.23     -10    22
# Comp:  2            [OI]6300_d      1.026      0.23     -10    22
# Comp:  2           [NII]6583_d      10.41      0.23     -10    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22        11
#  comp.  1:        -5        33
#  comp.  2:        -7        38
# chi2/DOF: 0.8975; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.07      0.19      -5    33
# Comp:  1                Halpha      39.68      0.19      -5    33
# Comp:  2             [SII]6716      7.740      0.19      -7    38
# Comp:  2             [SII]6731      5.600      0.19      -7    38
# Comp:  2              HeII4687    0.06135      0.19      -7    38
# Comp:  2               HeI5876      1.281      0.19      -7    38
# Comp:  2          [OIII]5007_d      14.20      0.24      -7    38
# Comp:  2            [OI]6300_d      1.252      0.24      -7    38
# Comp:  2           [NII]6583_d      10.56      0.24      -7    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        35
#  comp.  1:        -6        28
#  comp.  2:        -6        39
# chi2/DOF: 0.8746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.05      0.19      -6    28
# Comp:  1                Halpha      39.10      0.19      -6    28
# Comp:  2             [SII]6716      8.236      0.19      -6    39
# Comp:  2             [SII]6731      5.582      0.19      -6    39
# Comp:  2              HeII4687      0.000      0.19      -6    39
# Comp:  2               HeI5876      1.272      0.19      -6    39
# Comp:  2          [OIII]5007_d      14.61      0.24      -6    39
# Comp:  2            [OI]6300_d      1.187      0.24      -6    39
# Comp:  2           [NII]6583_d      10.41      0.24      -6    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        73
#  comp.  1:        -7        25
#  comp.  2:        -6        37
# chi2/DOF: 0.8689; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.13      0.19      -7    25
# Comp:  1                Halpha      38.74      0.19      -7    25
# Comp:  2             [SII]6716      8.104      0.19      -6    37
# Comp:  2             [SII]6731      5.052      0.19      -6    37
# Comp:  2              HeII4687      0.000      0.19      -6    37
# Comp:  2               HeI5876      1.351      0.19      -6    37
# Comp:  2          [OIII]5007_d      14.47      0.24      -6    37
# Comp:  2            [OI]6300_d      1.145      0.24      -6    37
# Comp:  2           [NII]6583_d      10.86      0.24      -6    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        -5        27
#  comp.  2:        -4        34
# chi2/DOF: 0.8876; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.46      0.19      -5    27
# Comp:  1                Halpha      39.26      0.19      -5    27
# Comp:  2             [SII]6716      7.895      0.19      -4    34
# Comp:  2             [SII]6731      5.335      0.19      -4    34
# Comp:  2              HeII4687    0.01190      0.19      -4    34
# Comp:  2               HeI5876      1.283      0.19      -4    34
# Comp:  2          [OIII]5007_d      13.31      0.24      -4    34
# Comp:  2            [OI]6300_d      1.193      0.24      -4    34
# Comp:  2           [NII]6583_d      10.28      0.24      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:        -8        28
#  comp.  2:        -9        26
# chi2/DOF: 0.8982; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.23      0.19      -8    28
# Comp:  1                Halpha      39.54      0.19      -8    28
# Comp:  2             [SII]6716      7.479      0.19      -9    26
# Comp:  2             [SII]6731      5.154      0.19      -9    26
# Comp:  2              HeII4687      0.000      0.19      -9    26
# Comp:  2               HeI5876      1.514      0.19      -9    26
# Comp:  2          [OIII]5007_d      12.85      0.23      -9    26
# Comp:  2            [OI]6300_d      1.157      0.23      -9    26
# Comp:  2           [NII]6583_d      10.15      0.23      -9    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -5        33
#  comp.  2:        -7        29
# chi2/DOF: 0.8865; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.32      0.19      -5    33
# Comp:  1                Halpha      39.87      0.19      -5    33
# Comp:  2             [SII]6716      7.782      0.19      -7    29
# Comp:  2             [SII]6731      5.559      0.19      -7    29
# Comp:  2              HeII4687     0.5499      0.19      -7    29
# Comp:  2               HeI5876      1.329      0.19      -7    29
# Comp:  2          [OIII]5007_d      13.62      0.24      -7    29
# Comp:  2            [OI]6300_d      1.277      0.24      -7    29
# Comp:  2           [NII]6583_d      10.55      0.24      -7    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -7        33
#  comp.  2:        -5        28
# chi2/DOF: 0.8619; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.40      0.19      -7    33
# Comp:  1                Halpha      40.50      0.19      -7    33
# Comp:  2             [SII]6716      7.337      0.19      -5    28
# Comp:  2             [SII]6731      5.028      0.19      -5    28
# Comp:  2              HeII4687     0.5041      0.19      -5    28
# Comp:  2               HeI5876      1.165      0.19      -5    28
# Comp:  2          [OIII]5007_d      13.31      0.24      -5    28
# Comp:  2            [OI]6300_d      1.274      0.24      -5    28
# Comp:  2           [NII]6583_d      10.26      0.24      -5    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        11
#  comp.  1:        -6        29
#  comp.  2:       -11        39
# chi2/DOF: 0.8737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.21      0.19      -6    29
# Comp:  1                Halpha      39.23      0.19      -6    29
# Comp:  2             [SII]6716      7.923      0.19     -11    39
# Comp:  2             [SII]6731      5.305      0.19     -11    39
# Comp:  2              HeII4687     0.2425      0.19     -11    39
# Comp:  2               HeI5876      1.320      0.19     -11    39
# Comp:  2          [OIII]5007_d      14.51      0.24     -11    39
# Comp:  2            [OI]6300_d      1.401      0.24     -11    39
# Comp:  2           [NII]6583_d      10.90      0.24     -11    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        31
#  comp.  1:        -6        26
#  comp.  2:        -5        31
# chi2/DOF: 0.8886; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.08      0.19      -6    26
# Comp:  1                Halpha      38.98      0.19      -6    26
# Comp:  2             [SII]6716      7.599      0.19      -5    31
# Comp:  2             [SII]6731      5.226      0.19      -5    31
# Comp:  2              HeII4687      0.000      0.19      -5    31
# Comp:  2               HeI5876      1.425      0.19      -5    31
# Comp:  2          [OIII]5007_d      13.29      0.24      -5    31
# Comp:  2            [OI]6300_d      1.008      0.24      -5    31
# Comp:  2           [NII]6583_d      10.38      0.24      -5    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        -6        33
#  comp.  2:        -9        42
# chi2/DOF: 0.8761; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.98      0.19      -6    33
# Comp:  1                Halpha      39.62      0.19      -6    33
# Comp:  2             [SII]6716      7.978      0.19      -9    42
# Comp:  2             [SII]6731      5.508      0.19      -9    42
# Comp:  2              HeII4687      0.000      0.19      -9    42
# Comp:  2               HeI5876      1.528      0.19      -9    42
# Comp:  2          [OIII]5007_d      14.71      0.25      -9    42
# Comp:  2            [OI]6300_d      1.044      0.25      -9    42
# Comp:  2           [NII]6583_d      10.88      0.25      -9    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:        -7        34
#  comp.  2:        -4        39
# chi2/DOF: 0.8559; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.54      0.19      -7    34
# Comp:  1                Halpha      40.51      0.19      -7    34
# Comp:  2             [SII]6716      8.065      0.19      -4    39
# Comp:  2             [SII]6731      5.397      0.19      -4    39
# Comp:  2              HeII4687     0.4543      0.19      -4    39
# Comp:  2               HeI5876      1.438      0.19      -4    39
# Comp:  2          [OIII]5007_d      13.51      0.24      -4    39
# Comp:  2            [OI]6300_d      1.092      0.24      -4    39
# Comp:  2           [NII]6583_d      10.45      0.24      -4    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45         1
#  comp.  1:        -9        29
#  comp.  2:        -8        39
# chi2/DOF: 0.8613; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.06      0.19      -9    29
# Comp:  1                Halpha      40.23      0.19      -9    29
# Comp:  2             [SII]6716      7.851      0.19      -8    39
# Comp:  2             [SII]6731      5.505      0.19      -8    39
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.08      0.19      -5    32
# Comp:  1                Halpha      39.57      0.19      -5    32
# Comp:  2             [SII]6716      7.220      0.18      -8    21
# Comp:  2             [SII]6731      5.189      0.18      -8    21
# Comp:  2              HeII4687      0.000      0.18      -8    21
# Comp:  2               HeI5876      1.281      0.18      -8    21
# Comp:  2          [OIII]5007_d      13.40      0.23      -8    21
# Comp:  2            [OI]6300_d      1.151      0.23      -8    21
# Comp:  2           [NII]6583_d      10.04      0.23      -8    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        -6        35
#  comp.  2:        -2        36
# chi2/DOF: 0.8890; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.26      0.19      -6    35
# Comp:  1                Halpha      40.34      0.19      -6    35
# Comp:  2             [SII]6716      7.828      0.19      -2    36
# Comp:  2             [SII]6731      5.365      0.19      -2    36
# Comp:  2              HeII4687      0.000      0.19      -2    36
# Comp:  2               HeI5876      1.273      0.19      -2    36
# Comp:  2          [OIII]5007_d      13.60      0.24      -2    36
# Comp:  2            [OI]6300_d      1.263      0.24      -2    36
# Comp:  2           [NII]6583_d      10.54      0.24      -2    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        26
#  comp.  1:        -7        31
#  comp.  2:        -7        40
# chi2/DOF: 0.9005; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.88      0.19      -7    31
# Comp:  1                Halpha      39.96      0.19      -7    31
# Comp:  2             [SII]6716      7.900      0.19      -7    40
# Comp:  2             [SII]6731      5.616      0.19      -7    40
# Comp:  2              HeII4687      0.000      0.19      -7    40
# Comp:  2               HeI5876      1.701      0.19      -7    40
# Comp:  2          [OIII]5007_d      14.14      0.24      -7    40
# Comp:  2            [OI]6300_d      1.171      0.24      -7    40
# Comp:  2           [NII]6583_d      10.68      0.24      -7    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        -7        30
#  comp.  2:       -10        24
# chi2/DOF: 0.8938; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.42      0.19      -7    30
# Comp:  1                Halpha      39.70      0.19      -7    30
# Comp:  2             [SII]6716      7.404      0.18     -10    24
# Comp:  2             [SII]6731      5.282      0.18     -10    24
# Comp:  2              HeII4687     0.5023      0.18     -10    24
# Comp:  2               HeI5876      1.287      0.18     -10    24
# Comp:  2          [OIII]5007_d      13.37      0.23     -10    24
# Comp:  2            [OI]6300_d      1.100      0.23     -10    24
# Comp:  2           [NII]6583_d      9.982      0.23     -10    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        49
#  comp.  1:        -9        26
#  comp.  2:        -7        29
# chi2/DOF: 0.8783; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.19      -9    26
# Comp:  1                Halpha      39.45      0.19      -9    26
# Comp:  2             [SII]6716      7.607      0.19      -7    29
# Comp:  2             [SII]6731      5.501      0.19      -7    29
# Comp:  2              HeII4687      0.000      0.19      -7    29
# Comp:  2               HeI5876      1.140      0.19      -7    29
# Comp:  2          [OIII]5007_d      13.35      0.24      -7    29
# Comp:  2            [OI]6300_d      1.158      0.24      -7    29
# Comp:  2           [NII]6583_d      10.30      0.24      -7    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67        17
#  comp.  1:        -7        27
#  comp.  2:        -7        22
# chi2/DOF: 0.8502; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.11      0.19      -7    27
# Comp:  1                Halpha      39.66      0.19      -7    27
# Comp:  2             [SII]6716      7.165      0.18      -7    22
# Comp:  2             [SII]6731      5.236      0.18      -7    22
# Comp:  2              HeII4687    0.02052      0.18      -7    22
# Comp:  2               HeI5876      1.329      0.18      -7    22
# Comp:  2          [OIII]5007_d      12.86      0.23      -7    22
# Comp:  2            [OI]6300_d      1.088      0.23      -7    22
# Comp:  2           [NII]6583_d      10.43      0.23      -7    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32         1
#  comp.  1:        -7        27
#  comp.  2:        -7        34
# chi2/DOF: 0.8887; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.16      0.19      -7    27
# Comp:  1                Halpha      39.21      0.19      -7    27
# Comp:  2             [SII]6716      7.827      0.19      -7    34
# Comp:  2             [SII]6731      5.566      0.19      -7    34
# Comp:  2              HeII4687     0.2551      0.19      -7    34
# Comp:  2               HeI5876      1.386      0.19      -7    34
# Comp:  2          [OIII]5007_d      13.22      0.24      -7    34
# Comp:  2            [OI]6300_d      1.147      0.24      -7    34
# Comp:  2           [NII]6583_d      10.51      0.24      -7    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        35
#  comp.  1:        -8        31
#  comp.  2:       -11        30
# chi2/DOF: 0.8910; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.47      0.19      -8    31
# Comp:  1                Halpha      40.33      0.19      -8    31
# Comp:  2             [SII]6716      7.523      0.19     -11    30
# Comp:  2             [SII]6731      5.286      0.19     -11    30
# Comp:  2              HeII4687     0.3029      0.19     -11    30
# Comp:  2               HeI5876      1.503      0.19     -11    30
# Comp:  2          [OIII]5007_d      13.93      0.24     -11    30
# Comp:  2            [OI]6300_d      1.166      0.24     -11    30
# Comp:  2           [NII]6583_d      10.48      0.24     -11    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44        23
#  comp.  1:        -8        30
#  comp.  2:        -4        46
# chi2/DOF: 0.8616; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.37      0.19      -8    30
# Comp:  1                Halpha      39.71      0.19      -8    30
# Comp:  2             [SII]6716      8.216      0.20      -4    46
# Comp:  2             [SII]6731      5.780      0.20      -4    46
# Comp:  2              HeII4687      0.000      0.20      -4    46
# Comp:  2               HeI5876      1.368      0.20      -4    46
# Comp:  2          [OIII]5007_d      14.07      0.25      -4    46
# Comp:  2            [OI]6300_d      1.023      0.25      -4    46
# Comp:  2           [NII]6583_d      10.79      0.25      -4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        -6        35
#  comp.  2:        -6        30
# chi2/DOF: 0.8865; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.21      0.19      -6    35
# Comp:  1                Halpha      40.64      0.19      -6    35
# Comp:  2             [SII]6716      7.863      0.19      -6    30
# Comp:  2             [SII]6731      5.412      0.19      -6    30
# Comp:  2              HeII4687      0.000      0.19      -6    30
# Comp:  2               HeI5876      1.170      0.19      -6    30
# Comp:  2          [OIII]5007_d      12.93      0.24      -6    30
# Comp:  2            [OI]6300_d      1.171      0.24      -6    30
# Comp:  2           [NII]6583_d      9.927      0.24      -6    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:        -6        30
#  comp.  2:       -11        25
# chi2/DOF: 0.8877; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.81      0.19      -6    30
# Comp:  1                Halpha      39.07      0.19      -6    30
# Comp:  2             [SII]6716      7.565      0.18     -11    25
# Comp:  2             [SII]6731      5.275      0.18     -11    25
# Comp:  2              HeII4687      0.000      0.18     -11    25
# Comp:  2               HeI5876      1.103      0.18     -11    25
# Comp:  2          [OIII]5007_d      13.77      0.23     -11    25
# Comp:  2            [OI]6300_d      1.077      0.23     -11    25
# Comp:  2           [NII]6583_d      10.05      0.23     -11    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54        46
#  comp.  1:        -7        26
#  comp.  2:        -7        30
# chi2/DOF: 0.8609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.96      0.19      -7    26
# Comp:  1                Halpha      39.10      0.19      -7    26
# Comp:  2             [SII]6716      7.850      0.19      -7    30
# Comp:  2             [SII]6731      5.202      0.19      -7    30
# Comp:  2              HeII4687      0.000      0.19      -7    30
# Comp:  2               HeI5876      1.224      0.19      -7    30
# Comp:  2          [OIII]5007_d      13.36      0.24      -7    30
# Comp:  2            [OI]6300_d      1.235      0.24      -7    30
# Comp:  2           [NII]6583_d      10.52      0.24      -7    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30       100
#  comp.  1:        -7        30
#  comp.  2:        -8        34
# chi2/DOF: 0.8938; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.88      0.19      -7    30
# Comp:  1                Halpha      39.67      0.19      -7    30
# Comp:  2             [SII]6716      7.926      0.19      -8    34
# Comp:  2             [SII]6731      5.287      0.19      -8    34
# Comp:  2              HeII4687     0.2320      0.19      -8    34
# Comp:  2               HeI5876      1.077      0.19      -8    34
# Comp:  2          [OIII]5007_d      13.07      0.24      -8    34
# Comp:  2            [OI]6300_d      1.352      0.24      -8    34
# Comp:  2           [NII]6583_d      10.15      0.24      -8    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        -7        35
#  comp.  2:       -10        35
# chi2/DOF: 0.8901; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.94      0.19      -7    35
# Comp:  1                Halpha      40.59      0.19      -7    35
# Comp:  2             [SII]6716      7.971      0.19     -10    35
# Comp:  2             [SII]6731      5.519      0.19     -10    35
# Comp:  2              HeII4687     0.4425      0.19     -10    35
# Comp:  2               HeI5876      1.345      0.19     -10    35
# Comp:  2          [OIII]5007_d      14.03      0.24     -10    35
# Comp:  2            [OI]6300_d      1.217      0.24     -10    35
# Comp:  2           [NII]6583_d      10.51      0.24     -10    35
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.05714166, 0.67151371, 0.37793909, 0.26516091, 0.16375152,
#        0.18300122, 0.57859224, 0.1270519 , 0.36330485])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([12.36208268, 54.30247891, 10.92511432,  7.53566281,  0.        ,
#         1.65547155, 14.40185065,  1.58502382, 14.31876159])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_6_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_6_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_6_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_6_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_6_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  1.090080    0.093218
# 1        Halpha  4.788355    0.059214
# 2     [SII]6716  0.963369    0.033326
# 3     [SII]6731  0.664490    0.023382
# 4      HeII4687  0.000000    0.014439
# 5       HeI5876  0.145978    0.016137
# 6  [OIII]5007_d  1.269945    0.051020
# 7    [OI]6300_d  0.139766    0.011203
# 8   [NII]6583_d  1.262618    0.032036
#           Name      Flux  Error_flux
# 0        Hbeta  1.090080    0.093218
# 1       Halpha  4.788355    0.059214
# 2    [SII]6716  0.963369    0.033326
# 3    [SII]6731  0.664490    0.023382
# 4     HeII4687  0.000000    0.014439
# 5      HeI5876  0.145978    0.016137
# 6   [OIII]4959  0.317486    0.051020
# 7   [OIII]5007  0.952459    0.051020
# 8     [OI]6300  0.104825    0.011203
# 9     [OI]6364  0.034942    0.011203
# 10   [NII]6548  0.315655    0.032036
# 11   [NII]6583  0.946964    0.032036

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0881793080592157
