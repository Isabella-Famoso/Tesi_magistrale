# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/redshift.txt") 
z = red[0][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18511937 2.18584583 2.18657229 ... 3.48184835 3.48257481 3.48330126]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3150, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314346256

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3150, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         9        15
# chi2/DOF: 0.03255; DOF: 1943; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
# chi2/DOF: 0.02210; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# [1.68489677 1.49493725 1.21712015 ... 1.0303593  0.785995   0.64940865]
# [1.19469339 1.20780644 1.20925523 ... 0.85473725 0.85812644 0.85380034]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([2.78113021, 0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        31         1
#  comp.  1:         1        26
#  comp.  2:        -7        29
# chi2/DOF: 0.6196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.63      0.46       1    26
# Comp:  1                Halpha      47.70      0.46       1    26
# Comp:  2             [SII]6716      8.778      0.47      -7    29
# Comp:  2             [SII]6731      6.258      0.47      -7    29
# Comp:  2              HeII4687     0.6812      0.47      -7    29
# Comp:  2               HeI5876      1.456      0.47      -7    29
# Comp:  2          [OIII]5007_d      24.31      0.59      -7    29
# Comp:  2            [OI]6300_d      1.276      0.59      -7    29
# Comp:  2           [NII]6583_d      11.43      0.59      -7    29
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  37.53; gas flux:     17 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  105.1; gas flux:     65 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  18.02; gas flux:     12 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  13.68; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.448; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.134; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  40.23; gas flux:     25 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.121; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  18.28; gas flux:     16 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        55        46
#  comp.  1:         3        37
#  comp.  2:        -5        15
# chi2/DOF: 0.5979; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.71      0.48       3    37
# Comp:  1                Halpha      50.11      0.48       3    37
# Comp:  2             [SII]6716      8.594      0.45      -5    15
# Comp:  2             [SII]6731      6.314      0.45      -5    15
# Comp:  2              HeII4687     0.6262      0.45      -5    15
# Comp:  2               HeI5876      1.370      0.45      -5    15
# Comp:  2          [OIII]5007_d      23.58      0.57      -5    15
# Comp:  2            [OI]6300_d     0.7228      0.57      -5    15
# Comp:  2           [NII]6583_d      10.97      0.57      -5    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31         1
#  comp.  1:         2        26
#  comp.  2:        -6        26
# chi2/DOF: 0.6107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.68      0.47       2    26
# Comp:  1                Halpha      47.71      0.47       2    26
# Comp:  2             [SII]6716      8.996      0.46      -6    26
# Comp:  2             [SII]6731      6.316      0.46      -6    26
# Comp:  2              HeII4687     0.4862      0.46      -6    26
# Comp:  2               HeI5876      1.678      0.46      -6    26
# Comp:  2          [OIII]5007_d      23.96      0.59      -6    26
# Comp:  2            [OI]6300_d      1.377      0.59      -6    26
# Comp:  2           [NII]6583_d      10.92      0.59      -6    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69         1
#  comp.  1:         1        23
#  comp.  2:        -4        34
# chi2/DOF: 0.6048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.19      0.46       1    23
# Comp:  1                Halpha      47.85      0.46       1    23
# Comp:  2             [SII]6716      8.127      0.48      -4    34
# Comp:  2             [SII]6731      6.706      0.48      -4    34
# Comp:  2              HeII4687     0.7406      0.48      -4    34
# Comp:  2               HeI5876      1.393      0.48      -4    34
# Comp:  2          [OIII]5007_d      23.42      0.60      -4    34
# Comp:  2            [OI]6300_d      1.445      0.60      -4    34
# Comp:  2           [NII]6583_d      11.40      0.60      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:         2        24
#  comp.  2:        -9        24
# chi2/DOF: 0.6098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.91      0.46       2    24
# Comp:  1                Halpha      47.39      0.46       2    24
# Comp:  2             [SII]6716      9.087      0.46      -9    24
# Comp:  2             [SII]6731      6.136      0.46      -9    24
# Comp:  2              HeII4687     0.7522      0.46      -9    24
# Comp:  2               HeI5876      1.582      0.46      -9    24
# Comp:  2          [OIII]5007_d      22.75      0.58      -9    24
# Comp:  2            [OI]6300_d      1.128      0.58      -9    24
# Comp:  2           [NII]6583_d      11.13      0.58      -9    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:        -2        17
#  comp.  2:        -8        28
# chi2/DOF: 0.6007; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.82      0.46      -2    17
# Comp:  1                Halpha      46.07      0.46      -2    17
# Comp:  2             [SII]6716      9.060      0.47      -8    28
# Comp:  2             [SII]6731      6.095      0.47      -8    28
# Comp:  2              HeII4687     0.7129      0.47      -8    28
# Comp:  2               HeI5876      1.291      0.47      -8    28
# Comp:  2          [OIII]5007_d      25.58      0.59      -8    28
# Comp:  2            [OI]6300_d      1.721      0.59      -8    28
# Comp:  2           [NII]6583_d      11.16      0.59      -8    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        50
#  comp.  1:         1        18
#  comp.  2:        -3        36
# chi2/DOF: 0.6053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.57      0.46       1    18
# Comp:  1                Halpha      47.13      0.46       1    18
# Comp:  2             [SII]6716      8.710      0.48      -3    36
# Comp:  2             [SII]6731      6.534      0.48      -3    36
# Comp:  2              HeII4687     0.6677      0.48      -3    36
# Comp:  2               HeI5876      1.653      0.48      -3    36
# Comp:  2          [OIII]5007_d      23.41      0.60      -3    36
# Comp:  2            [OI]6300_d      1.527      0.60      -3    36
# Comp:  2           [NII]6583_d      12.56      0.60      -3    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:         5        33
#  comp.  2:       -14        27
# chi2/DOF: 0.5964; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.06      0.47       5    33
# Comp:  1                Halpha      49.55      0.47       5    33
# Comp:  2             [SII]6716      8.744      0.47     -14    27
# Comp:  2             [SII]6731      6.429      0.47     -14    27
# Comp:  2              HeII4687     0.6626      0.47     -14    27
# Comp:  2               HeI5876      1.364      0.47     -14    27
# Comp:  2          [OIII]5007_d      24.14      0.59     -14    27
# Comp:  2            [OI]6300_d      1.497      0.59     -14    27
# Comp:  2           [NII]6583_d      10.48      0.59     -14    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60        47
#  comp.  1:        -2        16
#  comp.  2:        -4        41
# chi2/DOF: 0.5967; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.41      0.45      -2    16
# Comp:  1                Halpha      45.71      0.45      -2    16
# Comp:  2             [SII]6716      9.442      0.49      -4    41
# Comp:  2             [SII]6731      6.568      0.49      -4    41
# Comp:  2              HeII4687     0.8919      0.49      -4    41
# Comp:  2               HeI5876      1.618      0.49      -4    41
# Comp:  2          [OIII]5007_d      24.20      0.61      -4    41
# Comp:  2            [OI]6300_d      1.571      0.61      -4    41
# Comp:  2           [NII]6583_d      12.22      0.61      -4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54         1
#  comp.  1:         2        22
#  comp.  2:        -6        30
# chi2/DOF: 0.6125; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.57      0.46       2    22
# Comp:  1                Halpha      47.05      0.46       2    22
# Comp:  2             [SII]6716      9.317      0.47      -6    30
# Comp:  2             [SII]6731      6.134      0.47      -6    30
# Comp:  2              HeII4687     0.8275      0.47      -6    30
# Comp:  2               HeI5876      1.439      0.47      -6    30
# Comp:  2          [OIII]5007_d      24.47      0.59      -6    30
# Comp:  2            [OI]6300_d      1.467      0.59      -6    30
# Comp:  2           [NII]6583_d      11.54      0.59      -6    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        31
#  comp.  1:         5        34
#  comp.  2:        -7        28
# chi2/DOF: 0.5987; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.49      0.48       5    34
# Comp:  1                Halpha      49.61      0.48       5    34
# Comp:  2             [SII]6716      8.780      0.47      -7    28
# Comp:  2             [SII]6731      6.276      0.47      -7    28
# Comp:  2              HeII4687     0.4143      0.47      -7    28
# Comp:  2               HeI5876      1.715      0.47      -7    28
# Comp:  2          [OIII]5007_d      24.17      0.59      -7    28
# Comp:  2            [OI]6300_d      1.307      0.59      -7    28
# Comp:  2           [NII]6583_d      10.45      0.59      -7    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        22
#  comp.  1:        -3        11
#  comp.  2:        -8        20
# chi2/DOF: 0.5942; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.26      0.45      -3    11
# Comp:  1                Halpha      46.30      0.45      -3    11
# Comp:  2             [SII]6716      9.041      0.46      -8    20
# Comp:  2             [SII]6731      6.291      0.46      -8    20
# Comp:  2              HeII4687     0.7531      0.46      -8    20
# Comp:  2               HeI5876      1.650      0.46      -8    20
# Comp:  2          [OIII]5007_d      22.96      0.58      -8    20
# Comp:  2            [OI]6300_d      1.666      0.58      -8    20
# Comp:  2           [NII]6583_d      12.11      0.58      -8    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:         2        38
#  comp.  2:       -11        30
# chi2/DOF: 0.5888; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.65      0.48       2    38
# Comp:  1                Halpha      50.69      0.48       2    38
# Comp:  2             [SII]6716      8.544      0.47     -11    30
# Comp:  2             [SII]6731      6.314      0.47     -11    30
# Comp:  2              HeII4687     0.7265      0.47     -11    30
# Comp:  2               HeI5876      1.905      0.47     -11    30
# Comp:  2          [OIII]5007_d      22.72      0.59     -11    30
# Comp:  2            [OI]6300_d      1.021      0.59     -11    30
# Comp:  2           [NII]6583_d      11.16      0.59     -11    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45         1
#  comp.  1:         2        24
#  comp.  2:       -12        30
# chi2/DOF: 0.6121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.22      0.46       2    24
# Comp:  1                Halpha      47.91      0.46       2    24
# Comp:  2             [SII]6716      9.086      0.47     -12    30
# Comp:  2             [SII]6731      6.527      0.47     -12    30
# Comp:  2              HeII4687     0.5717      0.47     -12    30
# Comp:  2               HeI5876      1.464      0.47     -12    30
# Comp:  2          [OIII]5007_d      24.57      0.59     -12    30
# Comp:  2            [OI]6300_d      1.033      0.59     -12    30
# Comp:  2           [NII]6583_d      11.19      0.59     -12    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        29
#  comp.  1:         4        35
#  comp.  2:        -7        36
# chi2/DOF: 0.6037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.72      0.48       4    35
# Comp:  1                Halpha      49.75      0.48       4    35
# Comp:  2             [SII]6716      9.266      0.48      -7    36
# Comp:  2             [SII]6731      6.126      0.48      -7    36
# Comp:  2              HeII4687     0.6298      0.48      -7    36
# Comp:  2               HeI5876      1.727      0.48      -7    36
# Comp:  2          [OIII]5007_d      25.01      0.60      -7    36
# Comp:  2            [OI]6300_d      1.246      0.60      -7    36
# Comp:  2           [NII]6583_d      11.48      0.60      -7    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        32
#  comp.  1:        -1         9
#  comp.  2:        -9        27
# chi2/DOF: 0.5978; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.11      0.45      -1     9
# Comp:  1                Halpha      45.73      0.45      -1     9
# Comp:  2             [SII]6716      9.030      0.47      -9    27
# Comp:  2             [SII]6731      6.117      0.47      -9    27
# Comp:  2              HeII4687     0.5366      0.47      -9    27
# Comp:  2               HeI5876      1.628      0.47      -9    27
# Comp:  2          [OIII]5007_d      25.11      0.59      -9    27
# Comp:  2            [OI]6300_d      1.494      0.59      -9    27
# Comp:  2           [NII]6583_d      11.81      0.59      -9    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        52
#  comp.  1:         2        21
#  comp.  2:        -5        36
# chi2/DOF: 0.6063; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.09      0.46       2    21
# Comp:  1                Halpha      47.93      0.46       2    21
# Comp:  2             [SII]6716      8.460      0.48      -5    36
# Comp:  2             [SII]6731      6.293      0.48      -5    36
# Comp:  2              HeII4687     0.6760      0.48      -5    36
# Comp:  2               HeI5876      1.621      0.48      -5    36
# Comp:  2          [OIII]5007_d      26.34      0.60      -5    36
# Comp:  2            [OI]6300_d      1.365      0.60      -5    36
# Comp:  2           [NII]6583_d      11.79      0.60      -5    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        34
#  comp.  1:        -3        19
#  comp.  2:        -7         9
# chi2/DOF: 0.5970; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.99      0.46      -3    19
# Comp:  1                Halpha      46.15      0.46      -3    19
# Comp:  2             [SII]6716      9.004      0.45      -7     9
# Comp:  2             [SII]6731      5.930      0.45      -7     9
# Comp:  2              HeII4687     0.7307      0.45      -7     9
# Comp:  2               HeI5876      1.464      0.45      -7     9
# Comp:  2          [OIII]5007_d      22.30      0.57      -7     9
# Comp:  2            [OI]6300_d      1.276      0.57      -7     9
# Comp:  2           [NII]6583_d      11.24      0.57      -7     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32         1
#  comp.  1:         2        30
#  comp.  2:        -4        34
# chi2/DOF: 0.6098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.42      0.47       2    30
# Comp:  1                Halpha      47.69      0.47       2    30
# Comp:  2             [SII]6716      8.922      0.48      -4    34
# Comp:  2             [SII]6731      6.220      0.48      -4    34
# Comp:  2              HeII4687     0.5255      0.48      -4    34
# Comp:  2               HeI5876      1.712      0.48      -4    34
# Comp:  2          [OIII]5007_d      26.21      0.60      -4    34
# Comp:  2            [OI]6300_d      1.084      0.60      -4    34
# Comp:  2           [NII]6583_d      11.52      0.60      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:        -1        16
#  comp.  2:        -4        15
# chi2/DOF: 0.6047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.44      0.46      -1    16
# Comp:  1                Halpha      46.21      0.46      -1    16
# Comp:  2             [SII]6716      9.247      0.45      -4    15
# Comp:  2             [SII]6731      6.029      0.45      -4    15
# Comp:  2              HeII4687     0.6233      0.45      -4    15
# Comp:  2               HeI5876      1.310      0.45      -4    15
# Comp:  2          [OIII]5007_d      24.10      0.57      -4    15
# Comp:  2            [OI]6300_d      1.615      0.57      -4    15
# Comp:  2           [NII]6583_d      11.27      0.57      -4    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:        -1        18
#  comp.  2:       -10        39
# chi2/DOF: 0.6049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.23      0.46      -1    18
# Comp:  1                Halpha      46.29      0.46      -1    18
# Comp:  2             [SII]6716      8.187      0.48     -10    39
# Comp:  2             [SII]6731      6.342      0.48     -10    39
# Comp:  2              HeII4687     0.6007      0.48     -10    39
# Comp:  2               HeI5876      1.058      0.48     -10    39
# Comp:  2          [OIII]5007_d      24.43      0.61     -10    39
# Comp:  2            [OI]6300_d      1.395      0.61     -10    39
# Comp:  2           [NII]6583_d      11.68      0.61     -10    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69         1
#  comp.  1:         1        23
#  comp.  2:        -5        28
# chi2/DOF: 0.6082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.31      0.46       1    23
# Comp:  1                Halpha      47.51      0.46       1    23
# Comp:  2             [SII]6716      8.929      0.47      -5    28
# Comp:  2             [SII]6731      6.547      0.47      -5    28
# Comp:  2              HeII4687     0.8420      0.47      -5    28
# Comp:  2               HeI5876      1.644      0.47      -5    28
# Comp:  2          [OIII]5007_d      25.09      0.59      -5    28
# Comp:  2            [OI]6300_d      1.610      0.59      -5    28
# Comp:  2           [NII]6583_d      11.41      0.59      -5    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        13
#  comp.  1:        -1        20
#  comp.  2:       -10        30
# chi2/DOF: 0.6053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.92      0.46      -1    20
# Comp:  1                Halpha      45.82      0.46      -1    20
# Comp:  2             [SII]6716      9.033      0.47     -10    30
# Comp:  2             [SII]6731      6.193      0.47     -10    30
# Comp:  2              HeII4687     0.6978      0.47     -10    30
# Comp:  2               HeI5876      1.663      0.47     -10    30
# Comp:  2          [OIII]5007_d      24.84      0.59     -10    30
# Comp:  2            [OI]6300_d      1.366      0.59     -10    30
# Comp:  2           [NII]6583_d      10.91      0.59     -10    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67         1
#  comp.  1:         4        33
#  comp.  2:        -3        37
# chi2/DOF: 0.6016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.63      0.47       4    33
# Comp:  1                Halpha      49.77      0.47       4    33
# Comp:  2             [SII]6716      9.051      0.48      -3    37
# Comp:  2             [SII]6731      6.503      0.48      -3    37
# Comp:  2              HeII4687     0.6096      0.48      -3    37
# Comp:  2               HeI5876      1.270      0.48      -3    37
# Comp:  2          [OIII]5007_d      25.31      0.61      -3    37
# Comp:  2            [OI]6300_d      1.140      0.61      -3    37
# Comp:  2           [NII]6583_d      12.22      0.61      -3    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        26
#  comp.  1:         1        25
#  comp.  2:        -9        27
# chi2/DOF: 0.6094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.35      0.46       1    25
# Comp:  1                Halpha      48.30      0.46       1    25
# Comp:  2             [SII]6716      9.265      0.47      -9    27
# Comp:  2             [SII]6731      6.046      0.47      -9    27
# Comp:  2              HeII4687     0.8349      0.47      -9    27
# Comp:  2               HeI5876      1.595      0.47      -9    27
# Comp:  2          [OIII]5007_d      25.60      0.59      -9    27
# Comp:  2            [OI]6300_d      1.619      0.59      -9    27
# Comp:  2           [NII]6583_d      11.08      0.59      -9    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        66
#  comp.  1:         4        34
#  comp.  2:        -5        45
# chi2/DOF: 0.5927; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.27      0.48       4    34
# Comp:  1                Halpha      49.49      0.48       4    34
# Comp:  2             [SII]6716      10.13      0.49      -5    45
# Comp:  2             [SII]6731      6.220      0.49      -5    45
# Comp:  2              HeII4687     0.8592      0.49      -5    45
# Comp:  2               HeI5876      1.527      0.49      -5    45
# Comp:  2          [OIII]5007_d      26.67      0.62      -5    45
# Comp:  2            [OI]6300_d      1.018      0.62      -5    45
# Comp:  2           [NII]6583_d      12.64      0.62      -5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        62
#  comp.  1:        -2         1
#  comp.  2:        -6        36
# chi2/DOF: 0.5890; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.71      0.45      -2     1
# Comp:  1                Halpha      45.51      0.45      -2     1
# Comp:  2             [SII]6716      8.239      0.48      -6    36
# Comp:  2             [SII]6731      6.146      0.48      -6    36
# Comp:  2              HeII4687     0.7706      0.48      -6    36
# Comp:  2               HeI5876      1.746      0.48      -6    36
# Comp:  2          [OIII]5007_d      26.90      0.61      -6    36
# Comp:  2            [OI]6300_d      1.431      0.61      -6    36
# Comp:  2           [NII]6583_d      11.79      0.61      -6    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31         1
#  comp.  1:        -3        20
#  comp.  2:       -11        33
# chi2/DOF: 0.6035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.99      0.46      -3    20
# Comp:  1                Halpha      46.84      0.46      -3    20
# Comp:  2             [SII]6716      8.876      0.47     -11    33
# Comp:  2             [SII]6731      6.319      0.47     -11    33
# Comp:  2              HeII4687     0.6863      0.47     -11    33
# Comp:  2               HeI5876      1.516      0.47     -11    33
# Comp:  2          [OIII]5007_d      25.07      0.60     -11    33
# Comp:  2            [OI]6300_d      1.328      0.60     -11    33
# Comp:  2           [NII]6583_d      11.32      0.60     -11    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:         1        23
#  comp.  2:        -9        24
# chi2/DOF: 0.6138; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.37      0.46       1    23
# Comp:  1                Halpha      48.16      0.46       1    23
# Comp:  2             [SII]6716      8.891      0.46      -9    24
# Comp:  2             [SII]6731      6.385      0.46      -9    24
# Comp:  2              HeII4687     0.5223      0.46      -9    24
# Comp:  2               HeI5876      1.318      0.46      -9    24
# Comp:  2          [OIII]5007_d      23.23      0.58      -9    24
# Comp:  2            [OI]6300_d      1.429      0.58      -9    24
# Comp:  2           [NII]6583_d      11.26      0.58      -9    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        62         2
#  comp.  1:         1        24
#  comp.  2:        -4        34
# chi2/DOF: 0.6107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.30      0.46       1    24
# Comp:  1                Halpha      48.21      0.46       1    24
# Comp:  2             [SII]6716      8.644      0.48      -4    34
# Comp:  2             [SII]6731      6.209      0.48      -4    34
# Comp:  2              HeII4687     0.5590      0.48      -4    34
# Comp:  2               HeI5876      1.418      0.48      -4    34
# Comp:  2          [OIII]5007_d      23.56      0.60      -4    34
# Comp:  2            [OI]6300_d      1.322      0.60      -4    34
# Comp:  2           [NII]6583_d      12.18      0.60      -4    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        -1         9
#  comp.  2:        -9        15
# chi2/DOF: 0.5958; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.92      0.45      -1     9
# Comp:  1                Halpha      45.62      0.45      -1     9
# Comp:  2             [SII]6716      8.261      0.45      -9    15
# Comp:  2             [SII]6731      5.989      0.45      -9    15
# Comp:  2              HeII4687     0.6258      0.45      -9    15
# Comp:  2               HeI5876      1.551      0.45      -9    15
# Comp:  2          [OIII]5007_d      24.69      0.57      -9    15
# Comp:  2            [OI]6300_d     0.9974      0.57      -9    15
# Comp:  2           [NII]6583_d      10.88      0.57      -9    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:         4        35
#  comp.  2:        -7        34
# chi2/DOF: 0.6062; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.06      0.48       4    35
# Comp:  1                Halpha      49.43      0.48       4    35
# Comp:  2             [SII]6716      8.688      0.48      -7    34
# Comp:  2             [SII]6731      6.688      0.48      -7    34
# Comp:  2              HeII4687     0.5082      0.48      -7    34
# Comp:  2               HeI5876      1.341      0.48      -7    34
# Comp:  2          [OIII]5007_d      24.28      0.60      -7    34
# Comp:  2            [OI]6300_d      1.248      0.60      -7    34
# Comp:  2           [NII]6583_d      11.78      0.60      -7    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        64        90
#  comp.  1:         2        21
#  comp.  2:        -1        30
# chi2/DOF: 0.6011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.90      0.46       2    21
# Comp:  1                Halpha      47.13      0.46       2    21
# Comp:  2             [SII]6716      8.793      0.47      -1    30
# Comp:  2             [SII]6731      6.313      0.47      -1    30
# Comp:  2              HeII4687     0.6456      0.47      -1    30
# Comp:  2               HeI5876      1.287      0.47      -1    30
# Comp:  2          [OIII]5007_d      25.72      0.59      -1    30
# Comp:  2            [OI]6300_d     0.9089      0.59      -1    30
# Comp:  2           [NII]6583_d      11.55      0.59      -1    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:         3        18
#  comp.  2:        -2        31
# chi2/DOF: 0.6044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.68      0.46       3    18
# Comp:  1                Halpha      46.81      0.46       3    18
# Comp:  2             [SII]6716      8.905      0.47      -2    31
# Comp:  2             [SII]6731      6.095      0.47      -2    31
# Comp:  2              HeII4687     0.7538      0.47      -2    31
# Comp:  2               HeI5876      1.338      0.47      -2    31
# Comp:  2          [OIII]5007_d      26.18      0.60      -2    31
# Comp:  2            [OI]6300_d      1.275      0.60      -2    31
# Comp:  2           [NII]6583_d      10.89      0.60      -2    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25         1
#  comp.  1:        -1         8
#  comp.  2:        -0        28
# chi2/DOF: 0.5946; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.38      0.45      -1     8
# Comp:  1                Halpha      45.58      0.45      -1     8
# Comp:  2             [SII]6716      9.540      0.47      -0    28
# Comp:  2             [SII]6731      6.202      0.47      -0    28
# Comp:  2              HeII4687     0.6451      0.47      -0    28
# Comp:  2               HeI5876      1.660      0.47      -0    28
# Comp:  2          [OIII]5007_d      24.16      0.59      -0    28
# Comp:  2            [OI]6300_d      1.034      0.59      -0    28
# Comp:  2           [NII]6583_d      10.31      0.59      -0    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:        -1        17
#  comp.  2:        -8        28
# chi2/DOF: 0.6072; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.67      0.46      -1    17
# Comp:  1                Halpha      45.84      0.46      -1    17
# Comp:  2             [SII]6716      8.433      0.47      -8    28
# Comp:  2             [SII]6731      5.969      0.47      -8    28
# Comp:  2              HeII4687     0.9222      0.47      -8    28
# Comp:  2               HeI5876      1.768      0.47      -8    28
# Comp:  2          [OIII]5007_d      24.04      0.59      -8    28
# Comp:  2            [OI]6300_d      1.128      0.59      -8    28
# Comp:  2           [NII]6583_d      10.84      0.59      -8    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        66         1
#  comp.  1:         1        32
#  comp.  2:        -7        25
# chi2/DOF: 0.6074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.03      0.47       1    32
# Comp:  1                Halpha      47.99      0.47       1    32
# Comp:  2             [SII]6716      9.396      0.46      -7    25
# Comp:  2             [SII]6731      6.265      0.46      -7    25
# Comp:  2              HeII4687     0.5723      0.46      -7    25
# Comp:  2               HeI5876      1.566      0.46      -7    25
# Comp:  2          [OIII]5007_d      25.01      0.59      -7    25
# Comp:  2            [OI]6300_d      1.709      0.59      -7    25
# Comp:  2           [NII]6583_d      11.76      0.59      -7    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        45
#  comp.  1:        -1        29
#  comp.  2:        -3        22
# chi2/DOF: 0.6081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.07      0.47      -1    29
# Comp:  1                Halpha      48.26      0.47      -1    29
# Comp:  2             [SII]6716      8.083      0.46      -3    22
# Comp:  2             [SII]6731      5.971      0.46      -3    22
# Comp:  2              HeII4687     0.6337      0.46      -3    22
# Comp:  2               HeI5876      1.113      0.46      -3    22
# Comp:  2          [OIII]5007_d      24.94      0.58      -3    22
# Comp:  2            [OI]6300_d      1.198      0.58      -3    22
# Comp:  2           [NII]6583_d      11.67      0.58      -3    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22         1
#  comp.  1:        -1         7
#  comp.  2:        -6        38
# chi2/DOF: 0.5959; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.21      0.45      -1     7
# Comp:  1                Halpha      45.47      0.45      -1     7
# Comp:  2             [SII]6716      9.054      0.48      -6    38
# Comp:  2             [SII]6731      6.358      0.48      -6    38
# Comp:  2              HeII4687     0.7977      0.48      -6    38
# Comp:  2               HeI5876      1.277      0.48      -6    38
# Comp:  2          [OIII]5007_d      26.17      0.61      -6    38
# Comp:  2            [OI]6300_d      1.672      0.61      -6    38
# Comp:  2           [NII]6583_d      11.03      0.61      -6    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29         1
#  comp.  1:        -1         8
#  comp.  2:        -3        25
# chi2/DOF: 0.6026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.84      0.45      -1     8
# Comp:  1                Halpha      45.71      0.45      -1     8
# Comp:  2             [SII]6716      8.840      0.46      -3    25
# Comp:  2             [SII]6731      6.268      0.46      -3    25
# Comp:  2              HeII4687     0.5259      0.46      -3    25
# Comp:  2               HeI5876      1.547      0.46      -3    25
# Comp:  2          [OIII]5007_d      24.04      0.59      -3    25
# Comp:  2            [OI]6300_d     0.8159      0.59      -3    25
# Comp:  2           [NII]6583_d      11.06      0.59      -3    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        11
#  comp.  1:         1        29
#  comp.  2:        -7        41
# chi2/DOF: 0.6075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.98      0.47       1    29
# Comp:  1                Halpha      47.57      0.47       1    29
# Comp:  2             [SII]6716      8.868      0.49      -7    41
# Comp:  2             [SII]6731      6.301      0.49      -7    41
# Comp:  2              HeII4687     0.6763      0.49      -7    41
# Comp:  2               HeI5876      1.531      0.49      -7    41
# Comp:  2          [OIII]5007_d      26.03      0.61      -7    41
# Comp:  2            [OI]6300_d      1.082      0.61      -7    41
# Comp:  2           [NII]6583_d      11.40      0.61      -7    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37         1
#  comp.  1:         4        36
#  comp.  2:        -2        32
# chi2/DOF: 0.5980; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.83      0.48       4    36
# Comp:  1                Halpha      50.11      0.48       4    36
# Comp:  2             [SII]6716      9.108      0.47      -2    32
# Comp:  2             [SII]6731      6.245      0.47      -2    32
# Comp:  2              HeII4687     0.6356      0.47      -2    32
# Comp:  2               HeI5876      1.549      0.47      -2    32
# Comp:  2          [OIII]5007_d      23.20      0.60      -2    32
# Comp:  2            [OI]6300_d      1.121      0.60      -2    32
# Comp:  2           [NII]6583_d      11.41      0.60      -2    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        41
#  comp.  1:        -1        28
#  comp.  2:        -6        39
# chi2/DOF: 0.6041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.05      0.47      -1    28
# Comp:  1                Halpha      48.69      0.47      -1    28
# Comp:  2             [SII]6716      8.281      0.48      -6    39
# Comp:  2             [SII]6731      6.598      0.48      -6    39
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.96      0.46       2    24
# Comp:  1                Halpha      47.29      0.46       2    24
# Comp:  2             [SII]6716      8.313      0.45      -6    13
# Comp:  2             [SII]6731      5.825      0.45      -6    13
# Comp:  2              HeII4687     0.5790      0.45      -6    13
# Comp:  2               HeI5876      1.471      0.45      -6    13
# Comp:  2          [OIII]5007_d      24.55      0.57      -6    13
# Comp:  2            [OI]6300_d      1.229      0.57      -6    13
# Comp:  2           [NII]6583_d      10.68      0.57      -6    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39         1
#  comp.  1:         2        36
#  comp.  2:        -1        29
# chi2/DOF: 0.5984; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.65      0.48       2    36
# Comp:  1                Halpha      49.64      0.48       2    36
# Comp:  2             [SII]6716      8.698      0.47      -1    29
# Comp:  2             [SII]6731      6.120      0.47      -1    29
# Comp:  2              HeII4687     0.8267      0.47      -1    29
# Comp:  2               HeI5876      1.314      0.47      -1    29
# Comp:  2          [OIII]5007_d      25.48      0.59      -1    29
# Comp:  2            [OI]6300_d      1.350      0.59      -1    29
# Comp:  2           [NII]6583_d      11.26      0.59      -1    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
#  comp.  1:        -2        16
#  comp.  2:        -7        37
# chi2/DOF: 0.6009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.70      0.45      -2    16
# Comp:  1                Halpha      45.92      0.45      -2    16
# Comp:  2             [SII]6716      8.728      0.48      -7    37
# Comp:  2             [SII]6731      6.556      0.48      -7    37
# Comp:  2              HeII4687     0.7229      0.48      -7    37
# Comp:  2               HeI5876      1.950      0.48      -7    37
# Comp:  2          [OIII]5007_d      25.01      0.61      -7    37
# Comp:  2            [OI]6300_d      1.159      0.61      -7    37
# Comp:  2           [NII]6583_d      12.63      0.61      -7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        58
#  comp.  1:        -2        18
#  comp.  2:       -13        19
# chi2/DOF: 0.5987; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.23      0.46      -2    18
# Comp:  1                Halpha      46.38      0.46      -2    18
# Comp:  2             [SII]6716      8.361      0.46     -13    19
# Comp:  2             [SII]6731      6.244      0.46     -13    19
# Comp:  2              HeII4687     0.5452      0.46     -13    19
# Comp:  2               HeI5876      1.435      0.46     -13    19
# Comp:  2          [OIII]5007_d      22.43      0.58     -13    19
# Comp:  2            [OI]6300_d      1.187      0.58     -13    19
# Comp:  2           [NII]6583_d      11.29      0.58     -13    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59        43
#  comp.  1:         1        21
#  comp.  2:       -10        21
# chi2/DOF: 0.6074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.22      0.46       1    21
# Comp:  1                Halpha      48.16      0.46       1    21
# Comp:  2             [SII]6716      8.896      0.46     -10    21
# Comp:  2             [SII]6731      6.041      0.46     -10    21
# Comp:  2              HeII4687     0.5204      0.46     -10    21
# Comp:  2               HeI5876      1.188      0.46     -10    21
# Comp:  2          [OIII]5007_d      23.09      0.58     -10    21
# Comp:  2            [OI]6300_d      1.211      0.58     -10    21
# Comp:  2           [NII]6583_d      10.96      0.58     -10    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49        20
#  comp.  1:         0        24
#  comp.  2:        -7        17
# chi2/DOF: 0.6081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.72      0.46       0    24
# Comp:  1                Halpha      47.94      0.46       0    24
# Comp:  2             [SII]6716      8.369      0.46      -7    17
# Comp:  2             [SII]6731      6.245      0.46      -7    17
# Comp:  2              HeII4687     0.5951      0.46      -7    17
# Comp:  2               HeI5876      1.484      0.46      -7    17
# Comp:  2          [OIII]5007_d      21.84      0.58      -7    17
# Comp:  2            [OI]6300_d     0.9589      0.58      -7    17
# Comp:  2           [NII]6583_d      10.99      0.58      -7    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:        -1        14
#  comp.  2:        -1        29
# chi2/DOF: 0.6020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.39      0.45      -1    14
# Comp:  1                Halpha      45.44      0.45      -1    14
# Comp:  2             [SII]6716      8.011      0.47      -1    29
# Comp:  2             [SII]6731      6.268      0.47      -1    29
# Comp:  2              HeII4687     0.8550      0.47      -1    29
# Comp:  2               HeI5876      1.420      0.47      -1    29
# Comp:  2          [OIII]5007_d      24.38      0.59      -1    29
# Comp:  2            [OI]6300_d      1.072      0.59      -1    29
# Comp:  2           [NII]6583_d      11.52      0.59      -1    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45        44
#  comp.  1:         3        35
#  comp.  2:       -13        27
# chi2/DOF: 0.5993; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.62      0.48       3    35
# Comp:  1                Halpha      49.96      0.48       3    35
# Comp:  2             [SII]6716      8.925      0.47     -13    27
# Comp:  2             [SII]6731      6.101      0.47     -13    27
# Comp:  2              HeII4687     0.8044      0.47     -13    27
# Comp:  2               HeI5876      1.815      0.47     -13    27
# Comp:  2          [OIII]5007_d      23.08      0.59     -13    27
# Comp:  2            [OI]6300_d      1.236      0.59     -13    27
# Comp:  2           [NII]6583_d      11.10      0.59     -13    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60        60
#  comp.  1:         0        29
#  comp.  2:        -5        42
# chi2/DOF: 0.6081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.65      0.47       0    29
# Comp:  1                Halpha      48.08      0.47       0    29
# Comp:  2             [SII]6716      9.162      0.49      -5    42
# Comp:  2             [SII]6731      6.747      0.49      -5    42
# Comp:  2              HeII4687     0.6117      0.49      -5    42
# Comp:  2               HeI5876      1.352      0.49      -5    42
# Comp:  2          [OIII]5007_d      24.23      0.62      -5    42
# Comp:  2            [OI]6300_d      1.204      0.62      -5    42
# Comp:  2           [NII]6583_d      11.86      0.62      -5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:        -0        33
#  comp.  2:        -4        26
# chi2/DOF: 0.6093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.06      0.47      -0    33
# Comp:  1                Halpha      47.96      0.47      -0    33
# Comp:  2             [SII]6716      8.930      0.47      -4    26
# Comp:  2             [SII]6731      6.198      0.47      -4    26
# Comp:  2              HeII4687     0.7891      0.47      -4    26
# Comp:  2               HeI5876      1.067      0.47      -4    26
# Comp:  2          [OIII]5007_d      23.70      0.59      -4    26
# Comp:  2            [OI]6300_d      1.364      0.59      -4    26
# Comp:  2           [NII]6583_d      11.74      0.59      -4    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        -1        17
#  comp.  2:       -10        10
# chi2/DOF: 0.6017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.95      0.46      -1    17
# Comp:  1                Halpha      45.76      0.46      -1    17
# Comp:  2             [SII]6716      8.516      0.45     -10    10
# Comp:  2             [SII]6731      6.450      0.45     -10    10
# Comp:  2              HeII4687     0.7489      0.45     -10    10
# Comp:  2               HeI5876      1.066      0.45     -10    10
# Comp:  2          [OIII]5007_d      23.04      0.57     -10    10
# Comp:  2            [OI]6300_d     0.8081      0.57     -10    10
# Comp:  2           [NII]6583_d      11.48      0.57     -10    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45         1
#  comp.  1:         0        20
#  comp.  2:        -7         1
# chi2/DOF: 0.6064; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.86      0.46       0    20
# Comp:  1                Halpha      47.60      0.46       0    20
# Comp:  2             [SII]6716      8.534      0.45      -7     1
# Comp:  2             [SII]6731      5.899      0.45      -7     1
# Comp:  2              HeII4687     0.6077      0.45      -7     1
# Comp:  2               HeI5876      1.084      0.45      -7     1
# Comp:  2          [OIII]5007_d      22.28      0.57      -7     1
# Comp:  2            [OI]6300_d      1.400      0.57      -7     1
# Comp:  2           [NII]6583_d      10.46      0.57      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        24
#  comp.  1:        -3        18
#  comp.  2:       -11        27
# chi2/DOF: 0.6010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.47      0.46      -3    18
# Comp:  1                Halpha      46.08      0.46      -3    18
# Comp:  2             [SII]6716      8.401      0.47     -11    27
# Comp:  2             [SII]6731      5.806      0.47     -11    27
# Comp:  2              HeII4687     0.8364      0.47     -11    27
# Comp:  2               HeI5876      1.043      0.47     -11    27
# Comp:  2          [OIII]5007_d      22.54      0.59     -11    27
# Comp:  2            [OI]6300_d      1.633      0.59     -11    27
# Comp:  2           [NII]6583_d      10.93      0.59     -11    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:         0        35
#  comp.  2:       -13        38
# chi2/DOF: 0.5996; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      18.17      0.48       0    35
# Comp:  1                Halpha      48.57      0.48       0    35
# Comp:  2             [SII]6716      9.843      0.48     -13    38
# Comp:  2             [SII]6731      6.967      0.48     -13    38
# Comp:  2              HeII4687     0.6863      0.48     -13    38
# Comp:  2               HeI5876      1.570      0.48     -13    38
# Comp:  2          [OIII]5007_d      24.18      0.61     -13    38
# Comp:  2            [OI]6300_d      1.474      0.61     -13    38
# Comp:  2           [NII]6583_d      11.70      0.61     -13    38
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.69435606, 2.03340898, 0.66118582, 0.35973767, 0.09806593,
#        0.28114101, 1.26121137, 0.31185682, 0.66948677])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([16.86196937, 65.29033104, 12.29740386,  8.78534692,  0.6657688 ,
#         1.78392757, 25.38611753,  1.6761937 , 15.69902971])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.444908    0.018321
# 1        Halpha  1.722704    0.053652
# 2     [SII]6716  0.324470    0.017446
# 3     [SII]6731  0.231804    0.009492
# 4      HeII4687  0.017566    0.002587
# 5       HeI5876  0.047069    0.007418
# 6  [OIII]5007_d  0.669820    0.033277
# 7    [OI]6300_d  0.044227    0.008228
# 8   [NII]6583_d  0.414223    0.017665
#           Name      Flux  Error_flux
# 0        Hbeta  0.444908    0.018321
# 1       Halpha  1.722704    0.053652
# 2    [SII]6716  0.324470    0.017446
# 3    [SII]6731  0.231804    0.009492
# 4     HeII4687  0.017566    0.002587
# 5      HeI5876  0.047069    0.007418
# 6   [OIII]4959  0.167455    0.033277
# 7   [OIII]5007  0.502365    0.033277
# 8     [OI]6300  0.033170    0.008228
# 9     [OI]6364  0.011057    0.008228
# 10   [NII]6548  0.103556    0.017665
# 11   [NII]6583  0.310668    0.017665

# %%
np.median(flux_rf_rebin)
# Out:
# 0.02638528433536736
