# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_2/UGC-5823_2_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_2/UGC-5823_2_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     373   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        54   (2094, 964)   float32

# %%
image_cut = image[38:138, 0:1890]
image_error_cut = image_error[38:138, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 52*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax=np.percentile(image_cut, 95))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.0188
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_2/PSF/Real_seeing_UGC5823_2.txt")
sigma = seeing[0]/2.35

# %%
l_HB
# Out:
# 4952.386799999999

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),  # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 58.97376424456438
# differential_evolution step 2: f(x)= 58.97376424456438
# differential_evolution step 3: f(x)= 48.50604133174017
# differential_evolution step 4: f(x)= 48.50604133174017
# differential_evolution step 5: f(x)= 48.50604133174017
# differential_evolution step 6: f(x)= 48.50604133174017
# differential_evolution step 7: f(x)= 48.50604133174017
# differential_evolution step 8: f(x)= 44.85030499141961
# differential_evolution step 9: f(x)= 44.85030499141961
# differential_evolution step 10: f(x)= 44.85030499141961
# differential_evolution step 11: f(x)= 44.66643222254819
# differential_evolution step 12: f(x)= 44.66643222254819
# differential_evolution step 13: f(x)= 44.66643222254819
# differential_evolution step 14: f(x)= 44.27577714750485
# differential_evolution step 15: f(x)= 43.97493491519317
# differential_evolution step 16: f(x)= 43.87151566502573
# differential_evolution step 17: f(x)= 43.87151566502573
# differential_evolution step 18: f(x)= 43.87151566502573
# differential_evolution step 19: f(x)= 43.87151566502573
# differential_evolution step 20: f(x)= 43.662702916000704
# differential_evolution step 21: f(x)= 43.632531987658716
# differential_evolution step 22: f(x)= 43.632531987658716
# differential_evolution step 23: f(x)= 43.45348323902104
# differential_evolution step 24: f(x)= 43.45348323902104
# differential_evolution step 25: f(x)= 43.21446436244859
# differential_evolution step 26: f(x)= 43.21446436244859
# differential_evolution step 27: f(x)= 43.21446436244859
# differential_evolution step 28: f(x)= 43.21446436244859
# differential_evolution step 29: f(x)= 43.21446436244859
# differential_evolution step 30: f(x)= 43.21446436244859
# differential_evolution step 31: f(x)= 43.12807236764539
# differential_evolution step 32: f(x)= 43.073171121956044
# differential_evolution step 33: f(x)= 42.89856622935194
# differential_evolution step 34: f(x)= 42.89856622935194
# differential_evolution step 35: f(x)= 42.76601662695235
# differential_evolution step 36: f(x)= 42.55972116790553
# differential_evolution step 37: f(x)= 42.55972116790553
# differential_evolution step 38: f(x)= 42.55972116790553
# differential_evolution step 39: f(x)= 42.55972116790553
# differential_evolution step 40: f(x)= 42.55972116790553
# differential_evolution step 41: f(x)= 42.55972116790553
# differential_evolution step 42: f(x)= 42.51704861410022
# differential_evolution step 43: f(x)= 42.51536809469716
# differential_evolution step 44: f(x)= 42.51536809469716
# differential_evolution step 45: f(x)= 42.51536809469716
# differential_evolution step 46: f(x)= 42.51285752925619
# differential_evolution step 47: f(x)= 42.50086023928817
# differential_evolution step 48: f(x)= 42.39964189710773
# differential_evolution step 49: f(x)= 42.314680272450126
# differential_evolution step 50: f(x)= 42.22000353224966
# differential_evolution step 51: f(x)= 42.22000353224966
# differential_evolution step 52: f(x)= 42.22000353224966
# differential_evolution step 53: f(x)= 42.22000353224966
# differential_evolution step 54: f(x)= 42.10973770067443
# differential_evolution step 55: f(x)= 42.01422869335174
# differential_evolution step 56: f(x)= 42.00201412067717
# differential_evolution step 57: f(x)= 42.00201412067717
# differential_evolution step 58: f(x)= 42.00201412067717
# differential_evolution step 59: f(x)= 41.84869005116882
# differential_evolution step 60: f(x)= 41.76434478708022
# differential_evolution step 61: f(x)= 41.76434478708022
# differential_evolution step 62: f(x)= 41.68926617006288
# differential_evolution step 63: f(x)= 41.5771448982414
# differential_evolution step 64: f(x)= 41.5771448982414
# differential_evolution step 65: f(x)= 41.45051338158555
# differential_evolution step 66: f(x)= 41.45051338158555
# differential_evolution step 67: f(x)= 41.40324176209974
# differential_evolution step 68: f(x)= 41.16007032573815
# differential_evolution step 69: f(x)= 41.027791592953584
# differential_evolution step 70: f(x)= 41.027791592953584
# differential_evolution step 71: f(x)= 41.027791592953584
# differential_evolution step 72: f(x)= 41.027791592953584
# differential_evolution step 73: f(x)= 40.94303790329226
# differential_evolution step 74: f(x)= 40.77366156977915
# differential_evolution step 75: f(x)= 40.77366156977915
# differential_evolution step 76: f(x)= 40.76693211400866
# differential_evolution step 77: f(x)= 40.74404896062018
# differential_evolution step 78: f(x)= 40.65168877365011
# differential_evolution step 79: f(x)= 40.64453834966648
# differential_evolution step 80: f(x)= 40.64453834966648
# differential_evolution step 81: f(x)= 40.64453834966648
# differential_evolution step 82: f(x)= 40.64453834966648
# differential_evolution step 83: f(x)= 40.64453834966648
# differential_evolution step 84: f(x)= 40.64453834966648
# differential_evolution step 85: f(x)= 40.64453834966648
# differential_evolution step 86: f(x)= 40.64453834966648
# differential_evolution step 87: f(x)= 40.62144970957089
# differential_evolution step 88: f(x)= 40.62144970957089
# differential_evolution step 89: f(x)= 40.62144970957089
# differential_evolution step 90: f(x)= 40.62144970957089
# differential_evolution step 91: f(x)= 40.62144970957089
# differential_evolution step 92: f(x)= 40.62144970957089
# differential_evolution step 93: f(x)= 40.62144970957089
# differential_evolution step 94: f(x)= 40.62144970957089
# differential_evolution step 95: f(x)= 40.62144970957089
# differential_evolution step 96: f(x)= 40.62144970957089
# differential_evolution step 97: f(x)= 40.62144970957089
# differential_evolution step 98: f(x)= 40.62144970957089
# differential_evolution step 99: f(x)= 40.62144970957089
# differential_evolution step 100: f(x)= 40.62144970957089
# differential_evolution step 101: f(x)= 40.62144970957089
# differential_evolution step 102: f(x)= 40.62144970957089
# differential_evolution step 103: f(x)= 40.62144970957089
# differential_evolution step 104: f(x)= 40.62144970957089
# differential_evolution step 105: f(x)= 40.62144970957089
# differential_evolution step 106: f(x)= 40.62144970957089
# differential_evolution step 107: f(x)= 40.62144970957089
# differential_evolution step 108: f(x)= 40.57449681123154
# differential_evolution step 109: f(x)= 40.57449681123154
# differential_evolution step 110: f(x)= 40.57449681123154
# differential_evolution step 111: f(x)= 40.57449681123154
# differential_evolution step 112: f(x)= 40.57449681123154
# differential_evolution step 113: f(x)= 40.57449681123154
# differential_evolution step 114: f(x)= 40.5697726835478
# differential_evolution step 115: f(x)= 40.5697726835478
# differential_evolution step 116: f(x)= 40.5697726835478
# differential_evolution step 117: f(x)= 40.56178963620338
# differential_evolution step 118: f(x)= 40.56178963620338
# differential_evolution step 119: f(x)= 40.54628471421309
# differential_evolution step 120: f(x)= 40.54628471421309
# differential_evolution step 121: f(x)= 40.54628471421309
# differential_evolution step 122: f(x)= 40.54628471421309
# differential_evolution step 123: f(x)= 40.52949694240382
# differential_evolution step 124: f(x)= 40.52949694240382
# differential_evolution step 125: f(x)= 40.52949694240382
# differential_evolution step 126: f(x)= 40.52860647571495
# differential_evolution step 127: f(x)= 40.52860647571495
# differential_evolution step 128: f(x)= 40.52860647571495
# differential_evolution step 129: f(x)= 40.52860647571495
# differential_evolution step 130: f(x)= 40.51527803964835
# differential_evolution step 131: f(x)= 40.51527803964835
# differential_evolution step 132: f(x)= 40.51527803964835
# differential_evolution step 133: f(x)= 40.50191367208041
# differential_evolution step 134: f(x)= 40.50191367208041
# differential_evolution step 135: f(x)= 40.50191367208041
# differential_evolution step 136: f(x)= 40.50191367208041
# differential_evolution step 137: f(x)= 40.50191367208041
# differential_evolution step 138: f(x)= 40.49847216690318
# differential_evolution step 139: f(x)= 40.49847216690318
# differential_evolution step 140: f(x)= 40.49847216690318
# differential_evolution step 141: f(x)= 40.49847216690318
# differential_evolution step 142: f(x)= 40.49847216690318
# differential_evolution step 143: f(x)= 40.49847216690318
# differential_evolution step 144: f(x)= 40.49847216690318
# differential_evolution step 145: f(x)= 40.49847216690318
# differential_evolution step 146: f(x)= 40.49433980759815
# differential_evolution step 147: f(x)= 40.49432116204573
# differential_evolution step 148: f(x)= 40.49432116204573
# differential_evolution step 149: f(x)= 40.49432116204573
# differential_evolution step 150: f(x)= 40.49383936102299
# differential_evolution step 151: f(x)= 40.49383936102299
# differential_evolution step 152: f(x)= 40.49299247542255
# differential_evolution step 153: f(x)= 40.49299247542255
# differential_evolution step 154: f(x)= 40.49222377566839
# differential_evolution step 155: f(x)= 40.49222377566839
# differential_evolution step 156: f(x)= 40.49093161824147
# differential_evolution step 157: f(x)= 40.486225772352896
# differential_evolution step 158: f(x)= 40.486225772352896
# differential_evolution step 159: f(x)= 40.486225772352896
# differential_evolution step 160: f(x)= 40.486225772352896
# differential_evolution step 161: f(x)= 40.486225772352896
# differential_evolution step 162: f(x)= 40.486225772352896
# differential_evolution step 163: f(x)= 40.486225772352896
# differential_evolution step 164: f(x)= 40.486225772352896
# differential_evolution step 165: f(x)= 40.48376496349708
# differential_evolution step 166: f(x)= 40.48376496349708
# differential_evolution step 167: f(x)= 40.48376496349708
# differential_evolution step 168: f(x)= 40.48376496349708
# differential_evolution step 169: f(x)= 40.48376496349708
# differential_evolution step 170: f(x)= 40.48376496349708
# differential_evolution step 171: f(x)= 40.48376496349708
# differential_evolution step 172: f(x)= 40.48376496349708
# differential_evolution step 173: f(x)= 40.48376496349708
# differential_evolution step 174: f(x)= 40.48376496349708
# differential_evolution step 175: f(x)= 40.48376496349708
# differential_evolution step 176: f(x)= 40.48284864389368
# differential_evolution step 177: f(x)= 40.48284864389368
# differential_evolution step 178: f(x)= 40.48256995062638
# differential_evolution step 179: f(x)= 40.48256995062638
# differential_evolution step 180: f(x)= 40.48256995062638
# differential_evolution step 181: f(x)= 40.48248981448903
# differential_evolution step 182: f(x)= 40.48248981448903
# differential_evolution step 183: f(x)= 40.482153608813384
# differential_evolution step 184: f(x)= 40.482153608813384
# differential_evolution step 185: f(x)= 40.48154992585752
# differential_evolution step 186: f(x)= 40.48154992585752
# differential_evolution step 187: f(x)= 40.48142350994013
# differential_evolution step 188: f(x)= 40.48142350994013
# differential_evolution step 189: f(x)= 40.48142350994013
# differential_evolution step 190: f(x)= 40.481288754231926
# differential_evolution step 191: f(x)= 40.481288754231926
# differential_evolution step 192: f(x)= 40.481288754231926
# differential_evolution step 193: f(x)= 40.481288754231926
# differential_evolution step 194: f(x)= 40.48113094149273
# differential_evolution step 195: f(x)= 40.48113094149273
# differential_evolution step 196: f(x)= 40.48113094149273
# differential_evolution step 197: f(x)= 40.48105857082997
# differential_evolution step 198: f(x)= 40.480847024997956
# differential_evolution step 199: f(x)= 40.480847024997956
# differential_evolution step 200: f(x)= 40.480847024997956
# differential_evolution step 201: f(x)= 40.480847024997956
# differential_evolution step 202: f(x)= 40.48019163401507
# differential_evolution step 203: f(x)= 40.48019163401507
# differential_evolution step 204: f(x)= 40.48019163401507
# differential_evolution step 205: f(x)= 40.48019163401507
# differential_evolution step 206: f(x)= 40.48018997930693
# differential_evolution step 207: f(x)= 40.48018997930693
# differential_evolution step 208: f(x)= 40.48018997930693
# differential_evolution step 209: f(x)= 40.48018997930693
# differential_evolution step 210: f(x)= 40.48018997930693
# differential_evolution step 211: f(x)= 40.48018997930693
# differential_evolution step 212: f(x)= 40.48015656082797
# differential_evolution step 213: f(x)= 40.48015465527185
# differential_evolution step 214: f(x)= 40.48015134864717
# differential_evolution step 215: f(x)= 40.48015134864717
# differential_evolution step 216: f(x)= 40.48014978229931
# differential_evolution step 217: f(x)= 40.48014978229931
# differential_evolution step 218: f(x)= 40.48014978229931
# differential_evolution step 219: f(x)= 40.48014978229931
# differential_evolution step 220: f(x)= 40.48014978229931
# differential_evolution step 221: f(x)= 40.48014655556406
# differential_evolution step 222: f(x)= 40.48014655556406
# differential_evolution step 223: f(x)= 40.48014562037879
# differential_evolution step 224: f(x)= 40.48014562037879
# differential_evolution step 225: f(x)= 40.48014562037879
# differential_evolution step 226: f(x)= 40.48014562037879
# differential_evolution step 227: f(x)= 40.48014539645845
# differential_evolution step 228: f(x)= 40.48014539645845
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.67814600e-02 4.99999717e+01 4.48832479e+00 2.87914479e+01]
# Chi quadro minimo: 40.48014539645845

# %%
# Plots:
aic = np.zeros(8)
bic = np.zeros(8)
chi_quadr = np.zeros(8)
chi_quadro = np.zeros(8)
red_chi = np.zeros(8)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0083, r_e=76.9930, n=5.0057, x_0=28.7914
# [1.06072691e-01 6.29960887e+02 1.51686736e+01 3.47445783e-04]
# 1851.708296892826
# 1860.129349524405 0.0 1870.1289776367782 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 37
#      34 ax[0].grid(True)
#      35 #ax[0].tight_layout()
# ---> 37 ax[1].plot(x_axes, radial_profile_HA - y_fit)
#      38 #ax[1].set_ylim(-0.2, 0.2)
#      39 plt.savefig('AIC_1', bbox_inches='tight')
#
# ValueError: operands could not be broadcast together with shapes (100,) (120,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 899.0289544304754
# differential_evolution step 2: f(x)= 899.0289544304754
# differential_evolution step 3: f(x)= 520.5071592434604
# differential_evolution step 4: f(x)= 59.55404656959826
# differential_evolution step 5: f(x)= 59.55404656959826
# differential_evolution step 6: f(x)= 40.49073712333399
# differential_evolution step 7: f(x)= 39.82224897573204
# differential_evolution step 8: f(x)= 39.82224897573204
# differential_evolution step 9: f(x)= 39.82224897573204
# differential_evolution step 10: f(x)= 39.82224897573204
# differential_evolution step 11: f(x)= 39.82224897573204
# differential_evolution step 12: f(x)= 39.82224897573204
# differential_evolution step 13: f(x)= 35.708839811719514
# differential_evolution step 14: f(x)= 35.708839811719514
# differential_evolution step 15: f(x)= 34.80280323123106
# differential_evolution step 16: f(x)= 34.80280323123106
# differential_evolution step 17: f(x)= 34.80280323123106
# differential_evolution step 18: f(x)= 34.80280323123106
# differential_evolution step 19: f(x)= 34.80280323123106
# differential_evolution step 20: f(x)= 34.80280323123106
# differential_evolution step 21: f(x)= 20.10881767243395
# differential_evolution step 22: f(x)= 20.10881767243395
# differential_evolution step 23: f(x)= 20.10881767243395
# differential_evolution step 24: f(x)= 20.10881767243395
# differential_evolution step 25: f(x)= 20.10881767243395
# differential_evolution step 26: f(x)= 20.10881767243395
# differential_evolution step 27: f(x)= 20.10881767243395
# differential_evolution step 28: f(x)= 20.10881767243395
# differential_evolution step 29: f(x)= 20.10881767243395
# differential_evolution step 30: f(x)= 20.10881767243395
# differential_evolution step 31: f(x)= 20.10881767243395
# differential_evolution step 32: f(x)= 20.10881767243395
# differential_evolution step 33: f(x)= 20.10881767243395
# differential_evolution step 34: f(x)= 20.10881767243395
# differential_evolution step 35: f(x)= 19.172372647709675
# differential_evolution step 36: f(x)= 19.172372647709675
# differential_evolution step 37: f(x)= 19.172372647709675
# differential_evolution step 38: f(x)= 19.172372647709675
# differential_evolution step 39: f(x)= 19.172372647709675
# differential_evolution step 40: f(x)= 18.987453766383457
# differential_evolution step 41: f(x)= 18.987453766383457
# differential_evolution step 42: f(x)= 18.84006667339287
# differential_evolution step 43: f(x)= 18.84006667339287
# differential_evolution step 44: f(x)= 18.84006667339287
# differential_evolution step 45: f(x)= 18.83842841354035
# differential_evolution step 46: f(x)= 18.83842841354035
# differential_evolution step 47: f(x)= 18.83842841354035
# differential_evolution step 48: f(x)= 18.6614947911042
# differential_evolution step 49: f(x)= 18.573999836972902
# differential_evolution step 50: f(x)= 18.573999836972902
# differential_evolution step 51: f(x)= 18.573999836972902
# differential_evolution step 52: f(x)= 18.573999836972902
# differential_evolution step 53: f(x)= 18.568159928557584
# differential_evolution step 54: f(x)= 18.352815210874684
# differential_evolution step 55: f(x)= 18.352815210874684
# differential_evolution step 56: f(x)= 18.309339930846768
# differential_evolution step 57: f(x)= 18.309339930846768
# differential_evolution step 58: f(x)= 18.309339930846768
# differential_evolution step 59: f(x)= 18.309339930846768
# differential_evolution step 60: f(x)= 18.309339930846768
# differential_evolution step 61: f(x)= 18.309339930846768
# differential_evolution step 62: f(x)= 18.309339930846768
# differential_evolution step 63: f(x)= 18.30759357605292
# differential_evolution step 64: f(x)= 18.30759357605292
# differential_evolution step 65: f(x)= 18.269392164667615
# differential_evolution step 66: f(x)= 18.269392164667615
# differential_evolution step 67: f(x)= 18.269392164667615
# differential_evolution step 68: f(x)= 18.219067690791004
# differential_evolution step 69: f(x)= 18.21604110613591
# differential_evolution step 70: f(x)= 18.21604110613591
# differential_evolution step 71: f(x)= 18.21604110613591
# differential_evolution step 72: f(x)= 18.21604110613591
# differential_evolution step 73: f(x)= 18.21604110613591
# differential_evolution step 74: f(x)= 18.21604110613591
# differential_evolution step 75: f(x)= 18.21604110613591
# differential_evolution step 76: f(x)= 18.21604110613591
# differential_evolution step 77: f(x)= 18.159411091269018
# differential_evolution step 78: f(x)= 18.159411091269018
# differential_evolution step 79: f(x)= 18.159411091269018
# differential_evolution step 80: f(x)= 18.159411091269018
# differential_evolution step 81: f(x)= 18.159411091269018
# differential_evolution step 82: f(x)= 18.159411091269018
# differential_evolution step 83: f(x)= 18.159411091269018
# differential_evolution step 84: f(x)= 18.15296556931215
# differential_evolution step 85: f(x)= 18.141478820899838
# differential_evolution step 86: f(x)= 18.141478820899838
# differential_evolution step 87: f(x)= 18.141478820899838
# differential_evolution step 88: f(x)= 18.141478820899838
# differential_evolution step 89: f(x)= 18.1007364238477
# differential_evolution step 90: f(x)= 18.1007364238477
# differential_evolution step 91: f(x)= 18.1007364238477
# differential_evolution step 92: f(x)= 18.1007364238477
# differential_evolution step 93: f(x)= 18.1007364238477
# differential_evolution step 94: f(x)= 18.100497615240066
# differential_evolution step 95: f(x)= 18.100497615240066
# differential_evolution step 96: f(x)= 18.100497615240066
# differential_evolution step 97: f(x)= 18.095518598992783
# differential_evolution step 98: f(x)= 18.095518598992783
# differential_evolution step 99: f(x)= 18.095518598992783
# differential_evolution step 100: f(x)= 18.095518598992783
# differential_evolution step 101: f(x)= 18.078150228320638
# differential_evolution step 102: f(x)= 18.078150228320638
# differential_evolution step 103: f(x)= 18.078150228320638
# differential_evolution step 104: f(x)= 18.078150228320638
# differential_evolution step 105: f(x)= 18.078150228320638
# differential_evolution step 106: f(x)= 18.078150228320638
# differential_evolution step 107: f(x)= 18.078150228320638
# differential_evolution step 108: f(x)= 18.078150228320638
# differential_evolution step 109: f(x)= 18.078150228320638
# differential_evolution step 110: f(x)= 18.075957427459645
# differential_evolution step 111: f(x)= 18.075957427459645
# differential_evolution step 112: f(x)= 18.075957427459645
# differential_evolution step 113: f(x)= 18.075957427459645
# differential_evolution step 114: f(x)= 18.075957427459645
# differential_evolution step 115: f(x)= 18.075957427459645
# differential_evolution step 116: f(x)= 18.07452522162797
# differential_evolution step 117: f(x)= 18.07452522162797
# differential_evolution step 118: f(x)= 18.07452522162797
# differential_evolution step 119: f(x)= 18.07452522162797
# differential_evolution step 120: f(x)= 18.06814296786499
# differential_evolution step 121: f(x)= 18.06814296786499
# differential_evolution step 122: f(x)= 18.06814296786499
# differential_evolution step 123: f(x)= 18.06814296786499
# differential_evolution step 124: f(x)= 18.06814296786499
# differential_evolution step 125: f(x)= 18.06814296786499
# differential_evolution step 126: f(x)= 18.06814296786499
# differential_evolution step 127: f(x)= 18.06814296786499
# differential_evolution step 128: f(x)= 18.066510774267527
# differential_evolution step 129: f(x)= 18.066510774267527
# differential_evolution step 130: f(x)= 18.066510774267527
# differential_evolution step 131: f(x)= 18.066510774267527
# differential_evolution step 132: f(x)= 18.066510774267527
# differential_evolution step 133: f(x)= 18.066510774267527
# differential_evolution step 134: f(x)= 18.064528450334777
# differential_evolution step 135: f(x)= 18.064528450334777
# differential_evolution step 136: f(x)= 18.064528450334777
# differential_evolution step 137: f(x)= 18.064528450334777
# differential_evolution step 138: f(x)= 18.064528450334777
# differential_evolution step 139: f(x)= 18.064528450334777
# differential_evolution step 140: f(x)= 18.064528450334777
# differential_evolution step 141: f(x)= 18.064528450334777
# differential_evolution step 142: f(x)= 18.064528450334777
# differential_evolution step 143: f(x)= 18.06449873561797
# differential_evolution step 144: f(x)= 18.06449873561797
# differential_evolution step 145: f(x)= 18.063595885872907
# differential_evolution step 146: f(x)= 18.0630819700213
# differential_evolution step 147: f(x)= 18.062350101970644
# differential_evolution step 148: f(x)= 18.062350101970644
# differential_evolution step 149: f(x)= 18.061354408853862
# differential_evolution step 150: f(x)= 18.061354408853862
# differential_evolution step 151: f(x)= 18.061354408853862
# differential_evolution step 152: f(x)= 18.061354408853862
# differential_evolution step 153: f(x)= 18.061354408853862
# differential_evolution step 154: f(x)= 18.06129849703211
# differential_evolution step 155: f(x)= 18.061264729914594
# differential_evolution step 156: f(x)= 18.061264729914594
# differential_evolution step 157: f(x)= 18.061264729914594
# differential_evolution step 158: f(x)= 18.061264729914594
# differential_evolution step 159: f(x)= 18.060908950071106
# differential_evolution step 160: f(x)= 18.060132899244813
# differential_evolution step 161: f(x)= 18.060132899244813
# differential_evolution step 162: f(x)= 18.060132899244813
# differential_evolution step 163: f(x)= 18.060132899244813
# differential_evolution step 164: f(x)= 18.060132899244813
# differential_evolution step 165: f(x)= 18.05985871904777
# differential_evolution step 166: f(x)= 18.05985871904777
# differential_evolution step 167: f(x)= 18.05985871904777
# differential_evolution step 168: f(x)= 18.05951720909309
# differential_evolution step 169: f(x)= 18.05951720909309
# differential_evolution step 170: f(x)= 18.059426943719167
# differential_evolution step 171: f(x)= 18.059426943719167
# differential_evolution step 172: f(x)= 18.059401406546318
# differential_evolution step 173: f(x)= 18.058912962180354
# differential_evolution step 174: f(x)= 18.058770743209532
# differential_evolution step 175: f(x)= 18.058770743209532
# differential_evolution step 176: f(x)= 18.058520672622237
# differential_evolution step 177: f(x)= 18.058520672622237
# differential_evolution step 178: f(x)= 18.058520672622237
# differential_evolution step 179: f(x)= 18.05824450585533
# differential_evolution step 180: f(x)= 18.05824450585533
# differential_evolution step 181: f(x)= 18.05824450585533
# differential_evolution step 182: f(x)= 18.05824450585533
# differential_evolution step 183: f(x)= 18.05824450585533
# differential_evolution step 184: f(x)= 18.05824450585533
# differential_evolution step 185: f(x)= 18.05824444543905
# differential_evolution step 186: f(x)= 18.058191222626355
# differential_evolution step 187: f(x)= 18.058191222626355
# differential_evolution step 188: f(x)= 18.058158607784602
# differential_evolution step 189: f(x)= 18.058063925263106
# differential_evolution step 190: f(x)= 18.057665206604128
# differential_evolution step 191: f(x)= 18.05763478460345
# differential_evolution step 192: f(x)= 18.05763478460345
# differential_evolution step 193: f(x)= 18.057527266660607
# differential_evolution step 194: f(x)= 18.057497461389573
# differential_evolution step 195: f(x)= 18.05738529761473
# differential_evolution step 196: f(x)= 18.057315822937493
# differential_evolution step 197: f(x)= 18.057315822937493
# differential_evolution step 198: f(x)= 18.057315822937493
# differential_evolution step 199: f(x)= 18.057315822937493
# differential_evolution step 200: f(x)= 18.057315822937493
# differential_evolution step 201: f(x)= 18.057315822937493
# differential_evolution step 202: f(x)= 18.057282131341182
# differential_evolution step 203: f(x)= 18.05717073771762
# differential_evolution step 204: f(x)= 18.05710337282909
# differential_evolution step 205: f(x)= 18.057033227803203
# differential_evolution step 206: f(x)= 18.05701067183133
# differential_evolution step 207: f(x)= 18.05701067183133
# differential_evolution step 208: f(x)= 18.05701067183133
# differential_evolution step 209: f(x)= 18.05695984555834
# differential_evolution step 210: f(x)= 18.05695984555834
# differential_evolution step 211: f(x)= 18.056867912116385
# differential_evolution step 212: f(x)= 18.05683580872877
# differential_evolution step 213: f(x)= 18.056809977037865
# differential_evolution step 214: f(x)= 18.056809977037865
# differential_evolution step 215: f(x)= 18.056809977037865
# differential_evolution step 216: f(x)= 18.05677874410372
# differential_evolution step 217: f(x)= 18.05677874410372
# differential_evolution step 218: f(x)= 18.05677874410372
# differential_evolution step 219: f(x)= 18.056756063659957
# differential_evolution step 220: f(x)= 18.05671307840643
# differential_evolution step 221: f(x)= 18.05667334103197
# differential_evolution step 222: f(x)= 18.056624334494362
# differential_evolution step 223: f(x)= 18.056554642809616
# differential_evolution step 224: f(x)= 18.056554642809616
# differential_evolution step 225: f(x)= 18.056545430476973
# differential_evolution step 226: f(x)= 18.056542838697474
# differential_evolution step 227: f(x)= 18.056542838697474
# differential_evolution step 228: f(x)= 18.056542838697474
# differential_evolution step 229: f(x)= 18.056542838697474
# differential_evolution step 230: f(x)= 18.05644529041825
# differential_evolution step 231: f(x)= 18.05644529041825
# differential_evolution step 232: f(x)= 18.056410726289243
# differential_evolution step 233: f(x)= 18.056410726289243
# differential_evolution step 234: f(x)= 18.056410726289243
# differential_evolution step 235: f(x)= 18.056410726289243
# differential_evolution step 236: f(x)= 18.056410726289243
# differential_evolution step 237: f(x)= 18.056410726289243
# differential_evolution step 238: f(x)= 18.056410726289243
# differential_evolution step 239: f(x)= 18.056300313183442
# differential_evolution step 240: f(x)= 18.056300313183442
# differential_evolution step 241: f(x)= 18.056214063404422
# differential_evolution step 242: f(x)= 18.056214063404422
# differential_evolution step 243: f(x)= 18.056214063404422
# differential_evolution step 244: f(x)= 18.056214063404422
# differential_evolution step 245: f(x)= 18.056214063404422
# differential_evolution step 246: f(x)= 18.056214063404422
# differential_evolution step 247: f(x)= 18.056214063404422
# differential_evolution step 248: f(x)= 18.05621389218647
# differential_evolution step 249: f(x)= 18.05621389218647
# differential_evolution step 250: f(x)= 18.05621389218647
# differential_evolution step 251: f(x)= 18.05621389218647
# differential_evolution step 252: f(x)= 18.05621389218647
# differential_evolution step 253: f(x)= 18.05619820457252
# differential_evolution step 254: f(x)= 18.05619820457252
# differential_evolution step 255: f(x)= 18.05619820457252
# differential_evolution step 256: f(x)= 18.05619820457252
# differential_evolution step 257: f(x)= 18.05619820457252
# differential_evolution step 258: f(x)= 18.05619820457252
# differential_evolution step 259: f(x)= 18.05619820457252
# differential_evolution step 260: f(x)= 18.05619820457252
# differential_evolution step 261: f(x)= 18.05619820457252
# differential_evolution step 262: f(x)= 18.05619820457252
# differential_evolution step 263: f(x)= 18.05619820457252
# differential_evolution step 264: f(x)= 18.05619820457252
# differential_evolution step 265: f(x)= 18.05619820457252
# differential_evolution step 266: f(x)= 18.05619820457252
# differential_evolution step 267: f(x)= 18.05618584520256
# differential_evolution step 268: f(x)= 18.056178338411655
# differential_evolution step 269: f(x)= 18.05616322868519
# differential_evolution step 270: f(x)= 18.05616322868519
# differential_evolution step 271: f(x)= 18.056160741690153
# differential_evolution step 272: f(x)= 18.056160741690153
# differential_evolution step 273: f(x)= 18.056160741690153
# differential_evolution step 274: f(x)= 18.056160741690153
# differential_evolution step 275: f(x)= 18.056160741690153
# differential_evolution step 276: f(x)= 18.056160741690153
# differential_evolution step 277: f(x)= 18.056142565539187
# differential_evolution step 278: f(x)= 18.056142565539187
# differential_evolution step 279: f(x)= 18.056142565539187
# differential_evolution step 280: f(x)= 18.056142565539187
# differential_evolution step 281: f(x)= 18.056142565539187
# differential_evolution step 282: f(x)= 18.056142565539187
# differential_evolution step 283: f(x)= 18.056138323502253
# differential_evolution step 284: f(x)= 18.056136367236032
# differential_evolution step 285: f(x)= 18.056136367236032
# differential_evolution step 286: f(x)= 18.056136367236032
# differential_evolution step 287: f(x)= 18.056136367236032
# differential_evolution step 288: f(x)= 18.056136367236032
# differential_evolution step 289: f(x)= 18.056136367236032
# differential_evolution step 290: f(x)= 18.056136367236032
# differential_evolution step 291: f(x)= 18.056128255236633
# differential_evolution step 292: f(x)= 18.056128255236633
# differential_evolution step 293: f(x)= 18.056128255236633
# differential_evolution step 294: f(x)= 18.056128255236633
# differential_evolution step 295: f(x)= 18.056120506339393
# differential_evolution step 296: f(x)= 18.056120506339393
# differential_evolution step 297: f(x)= 18.056120506339393
# differential_evolution step 298: f(x)= 18.056120506339393
# differential_evolution step 299: f(x)= 18.056120506339393
# differential_evolution step 300: f(x)= 18.056120506339393
# differential_evolution step 301: f(x)= 18.056120506339393
# differential_evolution step 302: f(x)= 18.056117133796338
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 9.41088997  0.53993219  0.16146217 28.80147975  0.55604297 32.16986773
#   0.15115647 55.        ]
# Chi quadro minimo: 18.05611166769915

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\223936200.py:8: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=3.2070, r_e=0.9792, n=0.7888, x_0=28.7926
# Sérsic 2: I_e=0.2486, r_e=40.8403, n=0.0688, x_0=49.8237
# [10.53944285  0.69088373  3.50945463  0.20758578  0.17669261  8.2869071
#   0.06001806  1.72842876]
# 1089.4489147610727
# 1107.0313323434902 1089.4489147610727 1126.2902762489775 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (75, 79)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 4667.548339265089
# differential_evolution step 2: f(x)= 1109.0747672418909
# differential_evolution step 3: f(x)= 1060.1665451888152
# differential_evolution step 4: f(x)= 1060.1665451888152
# differential_evolution step 5: f(x)= 542.4839985549266
# differential_evolution step 6: f(x)= 288.0879621871101
# differential_evolution step 7: f(x)= 69.54090559726328
# differential_evolution step 8: f(x)= 29.39438786557547
# differential_evolution step 9: f(x)= 29.39438786557547
# differential_evolution step 10: f(x)= 29.39438786557547
# differential_evolution step 11: f(x)= 29.39438786557547
# differential_evolution step 12: f(x)= 29.39438786557547
# differential_evolution step 13: f(x)= 29.39438786557547
# differential_evolution step 14: f(x)= 29.39438786557547
# differential_evolution step 15: f(x)= 29.39438786557547
# differential_evolution step 16: f(x)= 29.39438786557547
# differential_evolution step 17: f(x)= 29.39438786557547
# differential_evolution step 18: f(x)= 29.39438786557547
# differential_evolution step 19: f(x)= 29.39438786557547
# differential_evolution step 20: f(x)= 29.39438786557547
# differential_evolution step 21: f(x)= 29.39438786557547
# differential_evolution step 22: f(x)= 29.39438786557547
# differential_evolution step 23: f(x)= 29.39438786557547
# differential_evolution step 24: f(x)= 21.764924908733228
# differential_evolution step 25: f(x)= 21.764924908733228
# differential_evolution step 26: f(x)= 21.764924908733228
# differential_evolution step 27: f(x)= 21.764924908733228
# differential_evolution step 28: f(x)= 21.764924908733228
# differential_evolution step 29: f(x)= 21.764924908733228
# differential_evolution step 30: f(x)= 21.764924908733228
# differential_evolution step 31: f(x)= 17.35058047896579
# differential_evolution step 32: f(x)= 17.35058047896579
# differential_evolution step 33: f(x)= 17.35058047896579
# differential_evolution step 34: f(x)= 14.725686741065884
# differential_evolution step 35: f(x)= 14.725686741065884
# differential_evolution step 36: f(x)= 14.725686741065884
# differential_evolution step 37: f(x)= 14.725686741065884
# differential_evolution step 38: f(x)= 14.725686741065884
# differential_evolution step 39: f(x)= 14.725686741065884
# differential_evolution step 40: f(x)= 14.70515542285868
# differential_evolution step 41: f(x)= 14.70515542285868
# differential_evolution step 42: f(x)= 14.70515542285868
# differential_evolution step 43: f(x)= 14.626362051596077
# differential_evolution step 44: f(x)= 9.85697500807443
# differential_evolution step 45: f(x)= 9.85697500807443
# differential_evolution step 46: f(x)= 9.85697500807443
# differential_evolution step 47: f(x)= 9.85697500807443
# differential_evolution step 48: f(x)= 9.85697500807443
# differential_evolution step 49: f(x)= 9.85697500807443
# differential_evolution step 50: f(x)= 9.475966948420373
# differential_evolution step 51: f(x)= 9.475966948420373
# differential_evolution step 52: f(x)= 9.475966948420373
# differential_evolution step 53: f(x)= 9.475966948420373
# differential_evolution step 54: f(x)= 9.475966948420373
# differential_evolution step 55: f(x)= 7.855941376105366
# differential_evolution step 56: f(x)= 7.398154994910757
# differential_evolution step 57: f(x)= 7.398154994910757
# differential_evolution step 58: f(x)= 7.398154994910757
# differential_evolution step 59: f(x)= 7.398154994910757
# differential_evolution step 60: f(x)= 7.398154994910757
# differential_evolution step 61: f(x)= 7.398154994910757
# differential_evolution step 62: f(x)= 7.398154994910757
# differential_evolution step 63: f(x)= 7.398154994910757
# differential_evolution step 64: f(x)= 7.398154994910757
# differential_evolution step 65: f(x)= 7.398154994910757
# differential_evolution step 66: f(x)= 7.398154994910757
# differential_evolution step 67: f(x)= 7.398154994910757
# differential_evolution step 68: f(x)= 7.398154994910757
# differential_evolution step 69: f(x)= 7.398154994910757
# differential_evolution step 70: f(x)= 7.398154994910757
# differential_evolution step 71: f(x)= 7.398154994910757
# differential_evolution step 72: f(x)= 7.398154994910757
# differential_evolution step 73: f(x)= 7.398154994910757
# differential_evolution step 74: f(x)= 6.577118639270018
# differential_evolution step 75: f(x)= 6.577118639270018
# differential_evolution step 76: f(x)= 6.577118639270018
# differential_evolution step 77: f(x)= 6.577118639270018
# differential_evolution step 78: f(x)= 6.577118639270018
# differential_evolution step 79: f(x)= 6.577118639270018
# differential_evolution step 80: f(x)= 6.509511708896888
# differential_evolution step 81: f(x)= 6.509511708896888
# differential_evolution step 82: f(x)= 6.509511708896888
# differential_evolution step 83: f(x)= 6.509511708896888
# differential_evolution step 84: f(x)= 6.509511708896888
# differential_evolution step 85: f(x)= 6.509511708896888
# differential_evolution step 86: f(x)= 6.509511708896888
# differential_evolution step 87: f(x)= 6.3727628063805
# differential_evolution step 88: f(x)= 6.3727628063805
# differential_evolution step 89: f(x)= 6.3727628063805
# differential_evolution step 90: f(x)= 6.3727628063805
# differential_evolution step 91: f(x)= 6.341640608025626
# differential_evolution step 92: f(x)= 6.341640608025626
# differential_evolution step 93: f(x)= 6.248085510523094
# differential_evolution step 94: f(x)= 6.248085510523094
# differential_evolution step 95: f(x)= 6.237960192692327
# differential_evolution step 96: f(x)= 6.193558553961239
# differential_evolution step 97: f(x)= 6.193558553961239
# differential_evolution step 98: f(x)= 6.193558553961239
# differential_evolution step 99: f(x)= 6.193558553961239
# differential_evolution step 100: f(x)= 6.193558553961239
# differential_evolution step 101: f(x)= 6.047764207988065
# differential_evolution step 102: f(x)= 6.047764207988065
# differential_evolution step 103: f(x)= 6.047764207988065
# differential_evolution step 104: f(x)= 6.047764207988065
# differential_evolution step 105: f(x)= 6.047764207988065
# differential_evolution step 106: f(x)= 6.034410485691436
# differential_evolution step 107: f(x)= 6.034410485691436
# differential_evolution step 108: f(x)= 6.034410485691436
# differential_evolution step 109: f(x)= 6.034410485691436
# differential_evolution step 110: f(x)= 6.034410485691436
# differential_evolution step 111: f(x)= 5.891094902242908
# differential_evolution step 112: f(x)= 5.891094902242908
# differential_evolution step 113: f(x)= 5.891094902242908
# differential_evolution step 114: f(x)= 5.891094902242908
# differential_evolution step 115: f(x)= 5.891094902242908
# differential_evolution step 116: f(x)= 5.891094902242908
# differential_evolution step 117: f(x)= 5.866608797809556
# differential_evolution step 118: f(x)= 5.866608797809556
# differential_evolution step 119: f(x)= 5.866608797809556
# differential_evolution step 120: f(x)= 5.866608797809556
# differential_evolution step 121: f(x)= 5.866608797809556
# differential_evolution step 122: f(x)= 5.852188234032194
# differential_evolution step 123: f(x)= 5.852188234032194
# differential_evolution step 124: f(x)= 5.836041854848571
# differential_evolution step 125: f(x)= 5.836041854848571
# differential_evolution step 126: f(x)= 5.828679282714433
# differential_evolution step 127: f(x)= 5.802543277310069
# differential_evolution step 128: f(x)= 5.802543277310069
# differential_evolution step 129: f(x)= 5.802543277310069
# differential_evolution step 130: f(x)= 5.802543277310069
# differential_evolution step 131: f(x)= 5.802543277310069
# differential_evolution step 132: f(x)= 5.802543277310069
# differential_evolution step 133: f(x)= 5.802543277310069
# differential_evolution step 134: f(x)= 5.802543277310069
# differential_evolution step 135: f(x)= 5.802543277310069
# differential_evolution step 136: f(x)= 5.802543277310069
# differential_evolution step 137: f(x)= 5.802543277310069
# differential_evolution step 138: f(x)= 5.802543277310069
# differential_evolution step 139: f(x)= 5.802543277310069
# differential_evolution step 140: f(x)= 5.766432849580932
# differential_evolution step 141: f(x)= 5.766432849580932
# differential_evolution step 142: f(x)= 5.766432849580932
# differential_evolution step 143: f(x)= 5.766432849580932
# differential_evolution step 144: f(x)= 5.766432849580932
# differential_evolution step 145: f(x)= 5.766432849580932
# differential_evolution step 146: f(x)= 5.766432849580932
# differential_evolution step 147: f(x)= 5.766432849580932
# differential_evolution step 148: f(x)= 5.766432849580932
# differential_evolution step 149: f(x)= 5.725460272212273
# differential_evolution step 150: f(x)= 5.725460272212273
# differential_evolution step 151: f(x)= 5.725460272212273
# differential_evolution step 152: f(x)= 5.725460272212273
# differential_evolution step 153: f(x)= 5.725460272212273
# differential_evolution step 154: f(x)= 5.725460272212273
# differential_evolution step 155: f(x)= 5.725460272212273
# differential_evolution step 156: f(x)= 5.725460272212273
# differential_evolution step 157: f(x)= 5.725460272212273
# differential_evolution step 158: f(x)= 5.725460272212273
# differential_evolution step 159: f(x)= 5.725460272212273
# differential_evolution step 160: f(x)= 5.725460272212273
# differential_evolution step 161: f(x)= 5.725460272212273
# differential_evolution step 162: f(x)= 5.725460272212273
# differential_evolution step 163: f(x)= 5.725460272212273
# differential_evolution step 164: f(x)= 5.725460272212273
# differential_evolution step 165: f(x)= 5.725460272212273
# differential_evolution step 166: f(x)= 5.725460272212273
# differential_evolution step 167: f(x)= 5.725460272212273
# differential_evolution step 168: f(x)= 5.725460272212273
# differential_evolution step 169: f(x)= 5.725460272212273
# differential_evolution step 170: f(x)= 5.725460272212273
# differential_evolution step 171: f(x)= 5.725460272212273
# differential_evolution step 172: f(x)= 5.725460272212273
# differential_evolution step 173: f(x)= 5.725460272212273
# differential_evolution step 174: f(x)= 5.725460272212273
# differential_evolution step 175: f(x)= 5.709675161500833
# differential_evolution step 176: f(x)= 5.709675161500833
# differential_evolution step 177: f(x)= 5.709675161500833
# differential_evolution step 178: f(x)= 5.690080891294
# differential_evolution step 179: f(x)= 5.690080891294
# differential_evolution step 180: f(x)= 5.690080891294
# differential_evolution step 181: f(x)= 5.690080891294
# differential_evolution step 182: f(x)= 5.690080891294
# differential_evolution step 183: f(x)= 5.690080891294
# differential_evolution step 184: f(x)= 5.690080891294
# differential_evolution step 185: f(x)= 5.669554963689049
# differential_evolution step 186: f(x)= 5.669554963689049
# differential_evolution step 187: f(x)= 5.6536372995967055
# differential_evolution step 188: f(x)= 5.6536372995967055
# differential_evolution step 189: f(x)= 5.645370964414697
# differential_evolution step 190: f(x)= 5.645370964414697
# differential_evolution step 191: f(x)= 5.638516217896314
# differential_evolution step 192: f(x)= 5.620627537791282
# differential_evolution step 193: f(x)= 5.620627537791282
# differential_evolution step 194: f(x)= 5.620627537791282
# differential_evolution step 195: f(x)= 5.620627537791282
# differential_evolution step 196: f(x)= 5.620627537791282
# differential_evolution step 197: f(x)= 5.620627537791282
# differential_evolution step 198: f(x)= 5.620627537791282
# differential_evolution step 199: f(x)= 5.600183036502312
# differential_evolution step 200: f(x)= 5.600183036502312
# differential_evolution step 201: f(x)= 5.600183036502312
# differential_evolution step 202: f(x)= 5.595477901809069
# differential_evolution step 203: f(x)= 5.595477901809069
# differential_evolution step 204: f(x)= 5.587309263466158
# differential_evolution step 205: f(x)= 5.587309263466158
# differential_evolution step 206: f(x)= 5.587309263466158
# differential_evolution step 207: f(x)= 5.587309263466158
# differential_evolution step 208: f(x)= 5.587309263466158
# differential_evolution step 209: f(x)= 5.587309263466158
# differential_evolution step 210: f(x)= 5.587309263466158
# differential_evolution step 211: f(x)= 5.587309263466158
# differential_evolution step 212: f(x)= 5.587309263466158
# differential_evolution step 213: f(x)= 5.587309263466158
# differential_evolution step 214: f(x)= 5.587309263466158
# differential_evolution step 215: f(x)= 5.587309263466158
# differential_evolution step 216: f(x)= 5.587309263466158
# differential_evolution step 217: f(x)= 5.587309263466158
# differential_evolution step 218: f(x)= 5.587309263466158
# differential_evolution step 219: f(x)= 5.587309263466158
# differential_evolution step 220: f(x)= 5.570453198197416
# differential_evolution step 221: f(x)= 5.570453198197416
# differential_evolution step 222: f(x)= 5.570453198197416
# differential_evolution step 223: f(x)= 5.570453198197416
# differential_evolution step 224: f(x)= 5.570453198197416
# differential_evolution step 225: f(x)= 5.570453198197416
# differential_evolution step 226: f(x)= 5.570453198197416
# differential_evolution step 227: f(x)= 5.570453198197416
# differential_evolution step 228: f(x)= 5.570453198197416
# differential_evolution step 229: f(x)= 5.570189541986282
# differential_evolution step 230: f(x)= 5.570189541986282
# differential_evolution step 231: f(x)= 5.570189541986282
# differential_evolution step 232: f(x)= 5.570189541986282
# differential_evolution step 233: f(x)= 5.570189541986282
# differential_evolution step 234: f(x)= 5.570189541986282
# differential_evolution step 235: f(x)= 5.570189541986282
# differential_evolution step 236: f(x)= 5.570189541986282
# differential_evolution step 237: f(x)= 5.5509234180340155
# differential_evolution step 238: f(x)= 5.5509234180340155
# differential_evolution step 239: f(x)= 5.5509234180340155
# differential_evolution step 240: f(x)= 5.5509234180340155
# differential_evolution step 241: f(x)= 5.5509234180340155
# differential_evolution step 242: f(x)= 5.5509234180340155
# differential_evolution step 243: f(x)= 5.549305850258237
# differential_evolution step 244: f(x)= 5.54080497997261
# differential_evolution step 245: f(x)= 5.53849110534081
# differential_evolution step 246: f(x)= 5.53849110534081
# differential_evolution step 247: f(x)= 5.529584295596957
# differential_evolution step 248: f(x)= 5.529584295596957
# differential_evolution step 249: f(x)= 5.529584295596957
# differential_evolution step 250: f(x)= 5.525569279337861
# differential_evolution step 251: f(x)= 5.525569279337861
# differential_evolution step 252: f(x)= 5.525569279337861
# differential_evolution step 253: f(x)= 5.525569279337861
# differential_evolution step 254: f(x)= 5.516592358021298
# differential_evolution step 255: f(x)= 5.508782338975797
# differential_evolution step 256: f(x)= 5.508782338975797
# differential_evolution step 257: f(x)= 5.508782338975797
# differential_evolution step 258: f(x)= 5.502460583181899
# differential_evolution step 259: f(x)= 5.502460583181899
# differential_evolution step 260: f(x)= 5.502460583181899
# differential_evolution step 261: f(x)= 5.502460583181899
# differential_evolution step 262: f(x)= 5.502460583181899
# differential_evolution step 263: f(x)= 5.501465363935374
# differential_evolution step 264: f(x)= 5.501465363935374
# differential_evolution step 265: f(x)= 5.501465363935374
# differential_evolution step 266: f(x)= 5.501465363935374
# differential_evolution step 267: f(x)= 5.501004040285737
# differential_evolution step 268: f(x)= 5.501004040285737
# differential_evolution step 269: f(x)= 5.501004040285737
# differential_evolution step 270: f(x)= 5.501004040285737
# differential_evolution step 271: f(x)= 5.495526281167762
# differential_evolution step 272: f(x)= 5.495526281167762
# differential_evolution step 273: f(x)= 5.495526281167762
# differential_evolution step 274: f(x)= 5.481008992993493
# differential_evolution step 275: f(x)= 5.479405865639696
# differential_evolution step 276: f(x)= 5.479405865639696
# differential_evolution step 277: f(x)= 5.479405865639696
# differential_evolution step 278: f(x)= 5.470740603365199
# differential_evolution step 279: f(x)= 5.470740603365199
# differential_evolution step 280: f(x)= 5.470740603365199
# differential_evolution step 281: f(x)= 5.470740603365199
# differential_evolution step 282: f(x)= 5.4528941933358315
# differential_evolution step 283: f(x)= 5.4528941933358315
# differential_evolution step 284: f(x)= 5.4528941933358315
# differential_evolution step 285: f(x)= 5.4528941933358315
# differential_evolution step 286: f(x)= 5.4490388886783245
# differential_evolution step 287: f(x)= 5.4490388886783245
# differential_evolution step 288: f(x)= 5.4490388886783245
# differential_evolution step 289: f(x)= 5.4490388886783245
# differential_evolution step 290: f(x)= 5.4490388886783245
# differential_evolution step 291: f(x)= 5.4490388886783245
# differential_evolution step 292: f(x)= 5.4490388886783245
# differential_evolution step 293: f(x)= 5.436830830222918
# differential_evolution step 294: f(x)= 5.387308175843438
# differential_evolution step 295: f(x)= 5.379066484573876
# differential_evolution step 296: f(x)= 5.379066484573876
# differential_evolution step 297: f(x)= 5.379066484573876
# differential_evolution step 298: f(x)= 5.379066484573876
# differential_evolution step 299: f(x)= 5.379066484573876
# differential_evolution step 300: f(x)= 5.379066484573876
# differential_evolution step 301: f(x)= 5.379066484573876
# differential_evolution step 302: f(x)= 5.379066484573876
# differential_evolution step 303: f(x)= 5.379066484573876
# differential_evolution step 304: f(x)= 5.379066484573876
# differential_evolution step 305: f(x)= 5.379066484573876
# differential_evolution step 306: f(x)= 5.379066484573876
# differential_evolution step 307: f(x)= 5.379066484573876
# differential_evolution step 308: f(x)= 5.379066484573876
# differential_evolution step 309: f(x)= 5.379066484573876
# differential_evolution step 310: f(x)= 5.379066484573876
# differential_evolution step 311: f(x)= 5.379066484573876
# differential_evolution step 312: f(x)= 5.379066484573876
# differential_evolution step 313: f(x)= 5.375399750464244
# differential_evolution step 314: f(x)= 5.369071688969916
# differential_evolution step 315: f(x)= 5.369071688969916
# differential_evolution step 316: f(x)= 5.369071688969916
# differential_evolution step 317: f(x)= 5.354408167812593
# differential_evolution step 318: f(x)= 5.354408167812593
# differential_evolution step 319: f(x)= 5.354408167812593
# differential_evolution step 320: f(x)= 5.354408167812593
# differential_evolution step 321: f(x)= 5.351573079936573
# differential_evolution step 322: f(x)= 5.343390990476731
# differential_evolution step 323: f(x)= 5.343390990476731
# differential_evolution step 324: f(x)= 5.343390990476731
# differential_evolution step 325: f(x)= 5.3424401733037845
# differential_evolution step 326: f(x)= 5.3424401733037845
# differential_evolution step 327: f(x)= 5.34162055540038
# differential_evolution step 328: f(x)= 5.334789070398824
# differential_evolution step 329: f(x)= 5.334789070398824
# differential_evolution step 330: f(x)= 5.33142706514094
# differential_evolution step 331: f(x)= 5.33142706514094
# differential_evolution step 332: f(x)= 5.318059964997559
# differential_evolution step 333: f(x)= 5.318059964997559
# differential_evolution step 334: f(x)= 5.318059964997559
# differential_evolution step 335: f(x)= 5.318059964997559
# differential_evolution step 336: f(x)= 5.318059964997559
# differential_evolution step 337: f(x)= 5.318059964997559
# differential_evolution step 338: f(x)= 5.318059964997559
# differential_evolution step 339: f(x)= 5.318059964997559
# differential_evolution step 340: f(x)= 5.310018667481594
# differential_evolution step 341: f(x)= 5.310018667481594
# differential_evolution step 342: f(x)= 5.310018667481594
# differential_evolution step 343: f(x)= 5.310018667481594
# differential_evolution step 344: f(x)= 5.310018667481594
# differential_evolution step 345: f(x)= 5.310018667481594
# differential_evolution step 346: f(x)= 5.310018667481594
# differential_evolution step 347: f(x)= 5.310018667481594
# differential_evolution step 348: f(x)= 5.302733974251524
# differential_evolution step 349: f(x)= 5.302733974251524
# differential_evolution step 350: f(x)= 5.302733974251524
# differential_evolution step 351: f(x)= 5.302733974251524
# differential_evolution step 352: f(x)= 5.302733974251524
# differential_evolution step 353: f(x)= 5.302733974251524
# differential_evolution step 354: f(x)= 5.2858627972582815
# differential_evolution step 355: f(x)= 5.2858627972582815
# differential_evolution step 356: f(x)= 5.2858627972582815
# differential_evolution step 357: f(x)= 5.2858627972582815
# differential_evolution step 358: f(x)= 5.2858627972582815
# differential_evolution step 359: f(x)= 5.283468669069373
# differential_evolution step 360: f(x)= 5.283468669069373
# differential_evolution step 361: f(x)= 5.283468669069373
# differential_evolution step 362: f(x)= 5.283468669069373
# differential_evolution step 363: f(x)= 5.283468669069373
# differential_evolution step 364: f(x)= 5.283468669069373
# differential_evolution step 365: f(x)= 5.283468669069373
# differential_evolution step 366: f(x)= 5.283468669069373
# differential_evolution step 367: f(x)= 5.283468669069373
# differential_evolution step 368: f(x)= 5.283468669069373
# differential_evolution step 369: f(x)= 5.283468669069373
# differential_evolution step 370: f(x)= 5.283468669069373
# differential_evolution step 371: f(x)= 5.283468669069373
# differential_evolution step 372: f(x)= 5.267945386926938
# differential_evolution step 373: f(x)= 5.267945386926938
# differential_evolution step 374: f(x)= 5.267945386926938
# differential_evolution step 375: f(x)= 5.267945386926938
# differential_evolution step 376: f(x)= 5.267945386926938
# differential_evolution step 377: f(x)= 5.267945386926938
# differential_evolution step 378: f(x)= 5.265175824993552
# differential_evolution step 379: f(x)= 5.265175824993552
# differential_evolution step 380: f(x)= 5.265175824993552
# differential_evolution step 381: f(x)= 5.265175824993552
# differential_evolution step 382: f(x)= 5.265175824993552
# differential_evolution step 383: f(x)= 5.265175824993552
# differential_evolution step 384: f(x)= 5.265175824993552
# differential_evolution step 385: f(x)= 5.263446309593409
# differential_evolution step 386: f(x)= 5.263446309593409
# differential_evolution step 387: f(x)= 5.263446309593409
# differential_evolution step 388: f(x)= 5.258683150118156
# differential_evolution step 389: f(x)= 5.258683150118156
# differential_evolution step 390: f(x)= 5.258683150118156
# differential_evolution step 391: f(x)= 5.258683150118156
# differential_evolution step 392: f(x)= 5.258683150118156
# differential_evolution step 393: f(x)= 5.258683150118156
# differential_evolution step 394: f(x)= 5.251656753139564
# differential_evolution step 395: f(x)= 5.251656753139564
# differential_evolution step 396: f(x)= 5.251656753139564
# differential_evolution step 397: f(x)= 5.251656753139564
# differential_evolution step 398: f(x)= 5.251656753139564
# differential_evolution step 399: f(x)= 5.248550919561342
# differential_evolution step 400: f(x)= 5.248550919561342
# differential_evolution step 401: f(x)= 5.248550919561342
# differential_evolution step 402: f(x)= 5.248550919561342
# differential_evolution step 403: f(x)= 5.248550919561342
# differential_evolution step 404: f(x)= 5.22779211499286
# differential_evolution step 405: f(x)= 5.22779211499286
# differential_evolution step 406: f(x)= 5.22779211499286
# differential_evolution step 407: f(x)= 5.22779211499286
# differential_evolution step 408: f(x)= 5.22779211499286
# differential_evolution step 409: f(x)= 5.22779211499286
# differential_evolution step 410: f(x)= 5.22779211499286
# differential_evolution step 411: f(x)= 5.22779211499286
# differential_evolution step 412: f(x)= 5.222505577890343
# differential_evolution step 413: f(x)= 5.222505577890343
# differential_evolution step 414: f(x)= 5.222505577890343
# differential_evolution step 415: f(x)= 5.222505577890343
# differential_evolution step 416: f(x)= 5.222505577890343
# differential_evolution step 417: f(x)= 5.222505577890343
# differential_evolution step 418: f(x)= 5.222505577890343
# differential_evolution step 419: f(x)= 5.222505577890343
# differential_evolution step 420: f(x)= 5.222505577890343
# differential_evolution step 421: f(x)= 5.222505577890343
# differential_evolution step 422: f(x)= 5.222505577890343
# differential_evolution step 423: f(x)= 5.222505577890343
# differential_evolution step 424: f(x)= 5.222505577890343
# differential_evolution step 425: f(x)= 5.222505577890343
# differential_evolution step 426: f(x)= 5.222505577890343
# differential_evolution step 427: f(x)= 5.215368632470439
# differential_evolution step 428: f(x)= 5.215368632470439
# differential_evolution step 429: f(x)= 5.215368632470439
# differential_evolution step 430: f(x)= 5.215368632470439
# differential_evolution step 431: f(x)= 5.215368632470439
# differential_evolution step 432: f(x)= 5.215368632470439
# differential_evolution step 433: f(x)= 5.210853551755849
# differential_evolution step 434: f(x)= 5.210853551755849
# differential_evolution step 435: f(x)= 5.206318051156247
# differential_evolution step 436: f(x)= 5.206318051156247
# differential_evolution step 437: f(x)= 5.206318051156247
# differential_evolution step 438: f(x)= 5.206318051156247
# differential_evolution step 439: f(x)= 5.203587790092103
# differential_evolution step 440: f(x)= 5.203587790092103
# differential_evolution step 441: f(x)= 5.203587790092103
# differential_evolution step 442: f(x)= 5.203587790092103
# differential_evolution step 443: f(x)= 5.203587790092103
# differential_evolution step 444: f(x)= 5.203587790092103
# differential_evolution step 445: f(x)= 5.203587790092103
# differential_evolution step 446: f(x)= 5.17782183052249
# differential_evolution step 447: f(x)= 5.17782183052249
# differential_evolution step 448: f(x)= 5.17782183052249
# differential_evolution step 449: f(x)= 5.17782183052249
# differential_evolution step 450: f(x)= 5.17782183052249
# differential_evolution step 451: f(x)= 5.17782183052249
# differential_evolution step 452: f(x)= 5.17782183052249
# differential_evolution step 453: f(x)= 5.17782183052249
# differential_evolution step 454: f(x)= 5.17782183052249
# differential_evolution step 455: f(x)= 5.17782183052249
# differential_evolution step 456: f(x)= 5.17782183052249
# differential_evolution step 457: f(x)= 5.17782183052249
# differential_evolution step 458: f(x)= 5.17782183052249
# differential_evolution step 459: f(x)= 5.17782183052249
# differential_evolution step 460: f(x)= 5.17782183052249
# differential_evolution step 461: f(x)= 5.1656593329298115
# differential_evolution step 462: f(x)= 5.161099261724083
# differential_evolution step 463: f(x)= 5.161099261724083
# differential_evolution step 464: f(x)= 5.161099261724083
# differential_evolution step 465: f(x)= 5.161099261724083
# differential_evolution step 466: f(x)= 5.161099261724083
# differential_evolution step 467: f(x)= 5.161099261724083
# differential_evolution step 468: f(x)= 5.159614543623502
# differential_evolution step 469: f(x)= 5.159614543623502
# differential_evolution step 470: f(x)= 5.159614543623502
# differential_evolution step 471: f(x)= 5.159614543623502
# differential_evolution step 472: f(x)= 5.159614543623502
# differential_evolution step 473: f(x)= 5.159614543623502
# differential_evolution step 474: f(x)= 5.159614543623502
# differential_evolution step 475: f(x)= 5.159614543623502
# differential_evolution step 476: f(x)= 5.159614543623502
# differential_evolution step 477: f(x)= 5.159614543623502
# differential_evolution step 478: f(x)= 5.159614543623502
# differential_evolution step 479: f(x)= 5.159614543623502
# differential_evolution step 480: f(x)= 5.159614543623502
# differential_evolution step 481: f(x)= 5.159614543623502
# differential_evolution step 482: f(x)= 5.159614543623502
# differential_evolution step 483: f(x)= 5.159614543623502
# differential_evolution step 484: f(x)= 5.159614543623502
# differential_evolution step 485: f(x)= 5.156524802818229
# differential_evolution step 486: f(x)= 5.156524802818229
# differential_evolution step 487: f(x)= 5.142632150979728
# differential_evolution step 488: f(x)= 5.142632150979728
# differential_evolution step 489: f(x)= 5.142632150979728
# differential_evolution step 490: f(x)= 5.142632150979728
# differential_evolution step 491: f(x)= 5.142632150979728
# differential_evolution step 492: f(x)= 5.142632150979728
# differential_evolution step 493: f(x)= 5.142632150979728
# differential_evolution step 494: f(x)= 5.135448180009873
# differential_evolution step 495: f(x)= 5.131294748774249
# differential_evolution step 496: f(x)= 5.131294748774249
# differential_evolution step 497: f(x)= 5.131294748774249
# differential_evolution step 498: f(x)= 5.130018628433743
# differential_evolution step 499: f(x)= 5.130018628433743
# differential_evolution step 500: f(x)= 5.130018628433743
# differential_evolution step 501: f(x)= 5.125926933767253
# differential_evolution step 502: f(x)= 5.125926933767253
# differential_evolution step 503: f(x)= 5.125926933767253
# differential_evolution step 504: f(x)= 5.125926933767253
# differential_evolution step 505: f(x)= 5.125926933767253
# differential_evolution step 506: f(x)= 5.125926933767253
# differential_evolution step 507: f(x)= 5.125926933767253
# differential_evolution step 508: f(x)= 5.112300690739421
# differential_evolution step 509: f(x)= 5.112300690739421
# differential_evolution step 510: f(x)= 5.112300690739421
# differential_evolution step 511: f(x)= 5.112300690739421
# differential_evolution step 512: f(x)= 5.112300690739421
# differential_evolution step 513: f(x)= 5.112300690739421
# differential_evolution step 514: f(x)= 5.112300690739421
# differential_evolution step 515: f(x)= 5.112300690739421
# differential_evolution step 516: f(x)= 5.112300690739421
# differential_evolution step 517: f(x)= 5.112300690739421
# differential_evolution step 518: f(x)= 5.112300690739421
# differential_evolution step 519: f(x)= 5.112300690739421
# differential_evolution step 520: f(x)= 5.112300690739421
# differential_evolution step 521: f(x)= 5.112300690739421
# differential_evolution step 522: f(x)= 5.112300690739421
# differential_evolution step 523: f(x)= 5.112300690739421
# differential_evolution step 524: f(x)= 5.112300690739421
# differential_evolution step 525: f(x)= 5.112300690739421
# differential_evolution step 526: f(x)= 5.112300690739421
# differential_evolution step 527: f(x)= 5.082067297129804
# differential_evolution step 528: f(x)= 5.082067297129804
# differential_evolution step 529: f(x)= 5.082067297129804
# differential_evolution step 530: f(x)= 5.082067297129804
# differential_evolution step 531: f(x)= 5.082067297129804
# differential_evolution step 532: f(x)= 5.082067297129804
# differential_evolution step 533: f(x)= 5.082067297129804
# differential_evolution step 534: f(x)= 5.082067297129804
# differential_evolution step 535: f(x)= 5.082067297129804
# differential_evolution step 536: f(x)= 5.082067297129804
# differential_evolution step 537: f(x)= 5.082067297129804
# differential_evolution step 538: f(x)= 5.082067297129804
# differential_evolution step 539: f(x)= 5.082067297129804
# differential_evolution step 540: f(x)= 5.082067297129804
# differential_evolution step 541: f(x)= 5.082067297129804
# differential_evolution step 542: f(x)= 5.082067297129804
# differential_evolution step 543: f(x)= 5.082067297129804
# differential_evolution step 544: f(x)= 5.082067297129804
# differential_evolution step 545: f(x)= 5.082067297129804
# differential_evolution step 546: f(x)= 5.082067297129804
# differential_evolution step 547: f(x)= 5.079511823275674
# differential_evolution step 548: f(x)= 5.079511823275674
# differential_evolution step 549: f(x)= 5.079511823275674
# differential_evolution step 550: f(x)= 5.079511823275674
# differential_evolution step 551: f(x)= 5.079511823275674
# differential_evolution step 552: f(x)= 5.079211459798956
# differential_evolution step 553: f(x)= 5.065271604115882
# differential_evolution step 554: f(x)= 5.065271604115882
# differential_evolution step 555: f(x)= 5.065271604115882
# differential_evolution step 556: f(x)= 5.065271604115882
# differential_evolution step 557: f(x)= 5.065271604115882
# differential_evolution step 558: f(x)= 5.047462485231382
# differential_evolution step 559: f(x)= 5.032984235144568
# differential_evolution step 560: f(x)= 5.032984235144568
# differential_evolution step 561: f(x)= 5.032984235144568
# differential_evolution step 562: f(x)= 5.032984235144568
# differential_evolution step 563: f(x)= 5.032984235144568
# differential_evolution step 564: f(x)= 5.032984235144568
# differential_evolution step 565: f(x)= 5.032984235144568
# differential_evolution step 566: f(x)= 5.032984235144568
# differential_evolution step 567: f(x)= 5.032984235144568
# differential_evolution step 568: f(x)= 5.032984235144568
# differential_evolution step 569: f(x)= 5.032984235144568
# differential_evolution step 570: f(x)= 5.032984235144568
# differential_evolution step 571: f(x)= 5.032984235144568
# differential_evolution step 572: f(x)= 5.032984235144568
# differential_evolution step 573: f(x)= 5.032984235144568
# differential_evolution step 574: f(x)= 5.032984235144568
# differential_evolution step 575: f(x)= 5.032984235144568
# differential_evolution step 576: f(x)= 5.032984235144568
# differential_evolution step 577: f(x)= 5.032984235144568
# differential_evolution step 578: f(x)= 5.032984235144568
# differential_evolution step 579: f(x)= 5.032984235144568
# differential_evolution step 580: f(x)= 5.032984235144568
# differential_evolution step 581: f(x)= 5.032984235144568
# differential_evolution step 582: f(x)= 5.032984235144568
# differential_evolution step 583: f(x)= 5.032984235144568
# differential_evolution step 584: f(x)= 5.032984235144568
# differential_evolution step 585: f(x)= 5.032984235144568
# differential_evolution step 586: f(x)= 5.032984235144568
# differential_evolution step 587: f(x)= 5.032984235144568
# differential_evolution step 588: f(x)= 5.032984235144568
# differential_evolution step 589: f(x)= 5.032984235144568
# differential_evolution step 590: f(x)= 5.032984235144568
# differential_evolution step 591: f(x)= 5.032984235144568
# differential_evolution step 592: f(x)= 5.032984235144568
# differential_evolution step 593: f(x)= 5.032984235144568
# differential_evolution step 594: f(x)= 5.032984235144568
# differential_evolution step 595: f(x)= 5.032984235144568
# differential_evolution step 596: f(x)= 5.032984235144568
# differential_evolution step 597: f(x)= 5.032984235144568
# differential_evolution step 598: f(x)= 5.032984235144568
# differential_evolution step 599: f(x)= 5.032984235144568
# differential_evolution step 600: f(x)= 5.032984235144568
# differential_evolution step 601: f(x)= 5.032984235144568
# differential_evolution step 602: f(x)= 5.032984235144568
# differential_evolution step 603: f(x)= 5.032984235144568
# differential_evolution step 604: f(x)= 5.032984235144568
# differential_evolution step 605: f(x)= 5.032984235144568
# differential_evolution step 606: f(x)= 5.032984235144568
# differential_evolution step 607: f(x)= 5.032984235144568
# differential_evolution step 608: f(x)= 5.032984235144568
# differential_evolution step 609: f(x)= 5.032984235144568
# differential_evolution step 610: f(x)= 5.032984235144568
# differential_evolution step 611: f(x)= 5.028535721483957
# differential_evolution step 612: f(x)= 5.028535721483957
# differential_evolution step 613: f(x)= 5.028535721483957
# differential_evolution step 614: f(x)= 5.028535721483957
# differential_evolution step 615: f(x)= 5.028535721483957
# differential_evolution step 616: f(x)= 5.028535721483957
# differential_evolution step 617: f(x)= 5.028535721483957
# differential_evolution step 618: f(x)= 5.028535721483957
# differential_evolution step 619: f(x)= 5.020023081674053
# differential_evolution step 620: f(x)= 5.015013361490207
# differential_evolution step 621: f(x)= 5.00154154427282
# differential_evolution step 622: f(x)= 5.00154154427282
# differential_evolution step 623: f(x)= 5.00154154427282
# differential_evolution step 624: f(x)= 5.00154154427282
# differential_evolution step 625: f(x)= 5.00154154427282
# differential_evolution step 626: f(x)= 5.00154154427282
# differential_evolution step 627: f(x)= 5.00154154427282
# differential_evolution step 628: f(x)= 5.00154154427282
# differential_evolution step 629: f(x)= 5.00154154427282
# differential_evolution step 630: f(x)= 5.00154154427282
# differential_evolution step 631: f(x)= 5.00154154427282
# differential_evolution step 632: f(x)= 5.00154154427282
# differential_evolution step 633: f(x)= 5.00154154427282
# differential_evolution step 634: f(x)= 5.00154154427282
# differential_evolution step 635: f(x)= 5.00154154427282
# differential_evolution step 636: f(x)= 5.00154154427282
# differential_evolution step 637: f(x)= 5.00154154427282
# differential_evolution step 638: f(x)= 5.00154154427282
# differential_evolution step 639: f(x)= 5.00154154427282
# differential_evolution step 640: f(x)= 5.00154154427282
# differential_evolution step 641: f(x)= 5.00154154427282
# differential_evolution step 642: f(x)= 5.00154154427282
# differential_evolution step 643: f(x)= 5.00154154427282
# differential_evolution step 644: f(x)= 5.00154154427282
# differential_evolution step 645: f(x)= 5.00154154427282
# differential_evolution step 646: f(x)= 5.00154154427282
# differential_evolution step 647: f(x)= 5.00154154427282
# differential_evolution step 648: f(x)= 5.00154154427282
# differential_evolution step 649: f(x)= 5.00154154427282
# differential_evolution step 650: f(x)= 5.00154154427282
# differential_evolution step 651: f(x)= 5.00154154427282
# differential_evolution step 652: f(x)= 5.00154154427282
# differential_evolution step 653: f(x)= 5.00154154427282
# differential_evolution step 654: f(x)= 5.00154154427282
# differential_evolution step 655: f(x)= 5.00154154427282
# differential_evolution step 656: f(x)= 5.00154154427282
# differential_evolution step 657: f(x)= 5.00154154427282
# differential_evolution step 658: f(x)= 5.00154154427282
# differential_evolution step 659: f(x)= 5.00154154427282
# differential_evolution step 660: f(x)= 5.00154154427282
# differential_evolution step 661: f(x)= 5.00154154427282
# differential_evolution step 662: f(x)= 5.00154154427282
# differential_evolution step 663: f(x)= 5.00154154427282
# differential_evolution step 664: f(x)= 5.00154154427282
# differential_evolution step 665: f(x)= 5.00154154427282
# differential_evolution step 666: f(x)= 5.00154154427282
# differential_evolution step 667: f(x)= 5.00154154427282
# differential_evolution step 668: f(x)= 5.00154154427282
# differential_evolution step 669: f(x)= 5.00154154427282
# differential_evolution step 670: f(x)= 5.00154154427282
# differential_evolution step 671: f(x)= 5.00154154427282
# differential_evolution step 672: f(x)= 5.00154154427282
# differential_evolution step 673: f(x)= 5.00154154427282
# differential_evolution step 674: f(x)= 5.00154154427282
# differential_evolution step 675: f(x)= 5.00154154427282
# differential_evolution step 676: f(x)= 5.00154154427282
# differential_evolution step 677: f(x)= 5.00154154427282
# differential_evolution step 678: f(x)= 5.00154154427282
# differential_evolution step 679: f(x)= 5.00154154427282
# differential_evolution step 680: f(x)= 5.00154154427282
# differential_evolution step 681: f(x)= 5.00154154427282
# differential_evolution step 682: f(x)= 5.000546010699172
# differential_evolution step 683: f(x)= 5.000546010699172
# differential_evolution step 684: f(x)= 5.000546010699172
# differential_evolution step 685: f(x)= 5.000546010699172
# differential_evolution step 686: f(x)= 5.000546010699172
# differential_evolution step 687: f(x)= 5.000546010699172
# differential_evolution step 688: f(x)= 5.000546010699172
# differential_evolution step 689: f(x)= 5.000546010699172
# differential_evolution step 690: f(x)= 5.000546010699172
# differential_evolution step 691: f(x)= 5.000546010699172
# differential_evolution step 692: f(x)= 5.000546010699172
# differential_evolution step 693: f(x)= 5.000546010699172
# differential_evolution step 694: f(x)= 4.991042089790305
# differential_evolution step 695: f(x)= 4.991042089790305
# differential_evolution step 696: f(x)= 4.991042089790305
# differential_evolution step 697: f(x)= 4.991042089790305
# differential_evolution step 698: f(x)= 4.991042089790305
# differential_evolution step 699: f(x)= 4.983641469165118
# differential_evolution step 700: f(x)= 4.983641469165118
# differential_evolution step 701: f(x)= 4.983641469165118
# differential_evolution step 702: f(x)= 4.983641469165118
# differential_evolution step 703: f(x)= 4.983641469165118
# differential_evolution step 704: f(x)= 4.983641469165118
# differential_evolution step 705: f(x)= 4.983641469165118
# differential_evolution step 706: f(x)= 4.9781074259313245
# differential_evolution step 707: f(x)= 4.9781074259313245
# differential_evolution step 708: f(x)= 4.9781074259313245
# differential_evolution step 709: f(x)= 4.968360473448461
# differential_evolution step 710: f(x)= 4.945966425985605
# differential_evolution step 711: f(x)= 4.913406435524694
# differential_evolution step 712: f(x)= 4.911037288175198
# differential_evolution step 713: f(x)= 4.911037288175198
# differential_evolution step 714: f(x)= 4.911037288175198
# differential_evolution step 715: f(x)= 4.911037288175198
# differential_evolution step 716: f(x)= 4.908437385579873
# differential_evolution step 717: f(x)= 4.897687342923637
# differential_evolution step 718: f(x)= 4.897687342923637
# differential_evolution step 719: f(x)= 4.897687342923637
# differential_evolution step 720: f(x)= 4.897687342923637
# differential_evolution step 721: f(x)= 4.897687342923637
# differential_evolution step 722: f(x)= 4.897687342923637
# differential_evolution step 723: f(x)= 4.897687342923637
# differential_evolution step 724: f(x)= 4.888703460029272
# differential_evolution step 725: f(x)= 4.861790122840813
# differential_evolution step 726: f(x)= 4.83430434906364
# differential_evolution step 727: f(x)= 4.83430434906364
# differential_evolution step 728: f(x)= 4.83430434906364
# differential_evolution step 729: f(x)= 4.83430434906364
# differential_evolution step 730: f(x)= 4.826332239396644
# differential_evolution step 731: f(x)= 4.826332239396644
# differential_evolution step 732: f(x)= 4.826332239396644
# differential_evolution step 733: f(x)= 4.826332239396644
# differential_evolution step 734: f(x)= 4.826332239396644
# differential_evolution step 735: f(x)= 4.826332239396644
# differential_evolution step 736: f(x)= 4.826332239396644
# differential_evolution step 737: f(x)= 4.826332239396644
# differential_evolution step 738: f(x)= 4.826332239396644
# differential_evolution step 739: f(x)= 4.826332239396644
# differential_evolution step 740: f(x)= 4.759796488200294
# differential_evolution step 741: f(x)= 4.759796488200294
# differential_evolution step 742: f(x)= 4.759796488200294
# differential_evolution step 743: f(x)= 4.759796488200294
# differential_evolution step 744: f(x)= 4.759796488200294
# differential_evolution step 745: f(x)= 4.759796488200294
# differential_evolution step 746: f(x)= 4.759796488200294
# differential_evolution step 747: f(x)= 4.759796488200294
# differential_evolution step 748: f(x)= 4.759796488200294
# differential_evolution step 749: f(x)= 4.759796488200294
# differential_evolution step 750: f(x)= 4.759796488200294
# differential_evolution step 751: f(x)= 4.759796488200294
# differential_evolution step 752: f(x)= 4.759796488200294
# differential_evolution step 753: f(x)= 4.759796488200294
# differential_evolution step 754: f(x)= 4.759796488200294
# differential_evolution step 755: f(x)= 4.759796488200294
# differential_evolution step 756: f(x)= 4.759796488200294
# differential_evolution step 757: f(x)= 4.759796488200294
# differential_evolution step 758: f(x)= 4.759796488200294
# differential_evolution step 759: f(x)= 4.737443369757717
# differential_evolution step 760: f(x)= 4.737443369757717
# differential_evolution step 761: f(x)= 4.737443369757717
# differential_evolution step 762: f(x)= 4.737443369757717
# differential_evolution step 763: f(x)= 4.681847323617738
# differential_evolution step 764: f(x)= 4.681847323617738
# differential_evolution step 765: f(x)= 4.681847323617738
# differential_evolution step 766: f(x)= 4.681847323617738
# differential_evolution step 767: f(x)= 4.681847323617738
# differential_evolution step 768: f(x)= 4.681847323617738
# differential_evolution step 769: f(x)= 4.681847323617738
# differential_evolution step 770: f(x)= 4.681847323617738
# differential_evolution step 771: f(x)= 4.622174749333956
# differential_evolution step 772: f(x)= 4.622174749333956
# differential_evolution step 773: f(x)= 4.622174749333956
# differential_evolution step 774: f(x)= 4.622174749333956
# differential_evolution step 775: f(x)= 4.622174749333956
# differential_evolution step 776: f(x)= 4.622174749333956
# differential_evolution step 777: f(x)= 4.622174749333956
# differential_evolution step 778: f(x)= 4.622174749333956
# differential_evolution step 779: f(x)= 4.622174749333956
# differential_evolution step 780: f(x)= 4.622174749333956
# differential_evolution step 781: f(x)= 4.622174749333956
# differential_evolution step 782: f(x)= 4.622174749333956
# differential_evolution step 783: f(x)= 4.622174749333956
# differential_evolution step 784: f(x)= 4.622174749333956
# differential_evolution step 785: f(x)= 4.622174749333956
# differential_evolution step 786: f(x)= 4.605711420499227
# differential_evolution step 787: f(x)= 4.605711420499227
# differential_evolution step 788: f(x)= 4.605711420499227
# differential_evolution step 789: f(x)= 4.605711420499227
# differential_evolution step 790: f(x)= 4.605711420499227
# differential_evolution step 791: f(x)= 4.605711420499227
# differential_evolution step 792: f(x)= 4.605711420499227
# differential_evolution step 793: f(x)= 4.605711420499227
# differential_evolution step 794: f(x)= 4.605711420499227
# differential_evolution step 795: f(x)= 4.605711420499227
# differential_evolution step 796: f(x)= 4.5915088878524335
# differential_evolution step 797: f(x)= 4.519660603177649
# differential_evolution step 798: f(x)= 4.519660603177649
# differential_evolution step 799: f(x)= 4.519660603177649
# differential_evolution step 800: f(x)= 4.519660603177649
# differential_evolution step 801: f(x)= 4.519660603177649
# differential_evolution step 802: f(x)= 4.519660603177649
# differential_evolution step 803: f(x)= 4.507603561985263
# differential_evolution step 804: f(x)= 4.483355151406891
# differential_evolution step 805: f(x)= 4.483355151406891
# differential_evolution step 806: f(x)= 4.483355151406891
# differential_evolution step 807: f(x)= 4.444910455317091
# differential_evolution step 808: f(x)= 4.444910455317091
# differential_evolution step 809: f(x)= 4.444910455317091
# differential_evolution step 810: f(x)= 4.444910455317091
# differential_evolution step 811: f(x)= 4.438155732226703
# differential_evolution step 812: f(x)= 4.377601278004065
# differential_evolution step 813: f(x)= 4.377601278004065
# differential_evolution step 814: f(x)= 4.327624036959455
# differential_evolution step 815: f(x)= 4.327624036959455
# differential_evolution step 816: f(x)= 4.281404965861605
# differential_evolution step 817: f(x)= 4.281404965861605
# differential_evolution step 818: f(x)= 4.281404965861605
# differential_evolution step 819: f(x)= 4.281404965861605
# differential_evolution step 820: f(x)= 4.281404965861605
# differential_evolution step 821: f(x)= 4.281404965861605
# differential_evolution step 822: f(x)= 4.281404965861605
# differential_evolution step 823: f(x)= 4.281404965861605
# differential_evolution step 824: f(x)= 4.281404965861605
# differential_evolution step 825: f(x)= 4.281404965861605
# differential_evolution step 826: f(x)= 4.281404965861605
# differential_evolution step 827: f(x)= 4.281404965861605
# differential_evolution step 828: f(x)= 4.281404965861605
# differential_evolution step 829: f(x)= 4.281404965861605
# differential_evolution step 830: f(x)= 4.281404965861605
# differential_evolution step 831: f(x)= 4.269738587571779
# differential_evolution step 832: f(x)= 4.269738587571779
# differential_evolution step 833: f(x)= 4.237826480611686
# differential_evolution step 834: f(x)= 4.237826480611686
# differential_evolution step 835: f(x)= 4.237826480611686
# differential_evolution step 836: f(x)= 4.237826480611686
# differential_evolution step 837: f(x)= 4.237826480611686
# differential_evolution step 838: f(x)= 4.237826480611686
# differential_evolution step 839: f(x)= 4.231889435139241
# differential_evolution step 840: f(x)= 4.231889435139241
# differential_evolution step 841: f(x)= 4.231889435139241
# differential_evolution step 842: f(x)= 4.231889435139241
# differential_evolution step 843: f(x)= 4.231889435139241
# differential_evolution step 844: f(x)= 4.231889435139241
# differential_evolution step 845: f(x)= 4.231889435139241
# differential_evolution step 846: f(x)= 4.231889435139241
# differential_evolution step 847: f(x)= 4.231889435139241
# differential_evolution step 848: f(x)= 4.193546122040035
# differential_evolution step 849: f(x)= 4.193546122040035
# differential_evolution step 850: f(x)= 4.193546122040035
# differential_evolution step 851: f(x)= 4.193546122040035
# differential_evolution step 852: f(x)= 4.180366009754954
# differential_evolution step 853: f(x)= 4.157122786340486
# differential_evolution step 854: f(x)= 4.157122786340486
# differential_evolution step 855: f(x)= 4.157122786340486
# differential_evolution step 856: f(x)= 4.0356477917485165
# differential_evolution step 857: f(x)= 4.0356477917485165
# differential_evolution step 858: f(x)= 4.0356477917485165
# differential_evolution step 859: f(x)= 4.0356477917485165
# differential_evolution step 860: f(x)= 4.0356477917485165
# differential_evolution step 861: f(x)= 4.0356477917485165
# differential_evolution step 862: f(x)= 4.0356477917485165
# differential_evolution step 863: f(x)= 4.027040629479362
# differential_evolution step 864: f(x)= 4.009052549851533
# differential_evolution step 865: f(x)= 4.009052549851533
# differential_evolution step 866: f(x)= 4.009052549851533
# differential_evolution step 867: f(x)= 4.009052549851533
# differential_evolution step 868: f(x)= 4.009052549851533
# differential_evolution step 869: f(x)= 4.009052549851533
# differential_evolution step 870: f(x)= 4.009052549851533
# differential_evolution step 871: f(x)= 4.009052549851533
# differential_evolution step 872: f(x)= 4.009052549851533
# differential_evolution step 873: f(x)= 4.009052549851533
# differential_evolution step 874: f(x)= 4.009052549851533
# differential_evolution step 875: f(x)= 4.009052549851533
# differential_evolution step 876: f(x)= 4.009052549851533
# differential_evolution step 877: f(x)= 4.009052549851533
# differential_evolution step 878: f(x)= 4.009052549851533
# differential_evolution step 879: f(x)= 4.009052549851533
# differential_evolution step 880: f(x)= 3.9932553399655055
# differential_evolution step 881: f(x)= 3.9932553399655055
# differential_evolution step 882: f(x)= 3.966721832789587
# differential_evolution step 883: f(x)= 3.966721832789587
# differential_evolution step 884: f(x)= 3.960695015400942
# differential_evolution step 885: f(x)= 3.960695015400942
# differential_evolution step 886: f(x)= 3.960695015400942
# differential_evolution step 887: f(x)= 3.960695015400942
# differential_evolution step 888: f(x)= 3.960695015400942
# differential_evolution step 889: f(x)= 3.960695015400942
# differential_evolution step 890: f(x)= 3.960695015400942
# differential_evolution step 891: f(x)= 3.960695015400942
# differential_evolution step 892: f(x)= 3.960695015400942
# differential_evolution step 893: f(x)= 3.960695015400942
# differential_evolution step 894: f(x)= 3.960695015400942
# differential_evolution step 895: f(x)= 3.960695015400942
# differential_evolution step 896: f(x)= 3.960695015400942
# differential_evolution step 897: f(x)= 3.960695015400942
# differential_evolution step 898: f(x)= 3.960695015400942
# differential_evolution step 899: f(x)= 3.960695015400942
# differential_evolution step 900: f(x)= 3.960695015400942
# differential_evolution step 901: f(x)= 3.960695015400942
# differential_evolution step 902: f(x)= 3.960695015400942
# differential_evolution step 903: f(x)= 3.960695015400942
# differential_evolution step 904: f(x)= 3.9481050878643362
# differential_evolution step 905: f(x)= 3.9481050878643362
# differential_evolution step 906: f(x)= 3.9481050878643362
# differential_evolution step 907: f(x)= 3.9481050878643362
# differential_evolution step 908: f(x)= 3.9481050878643362
# differential_evolution step 909: f(x)= 3.9481050878643362
# differential_evolution step 910: f(x)= 3.9481050878643362
# differential_evolution step 911: f(x)= 3.9481050878643362
# differential_evolution step 912: f(x)= 3.9481050878643362
# differential_evolution step 913: f(x)= 3.9481050878643362
# differential_evolution step 914: f(x)= 3.9481050878643362
# differential_evolution step 915: f(x)= 3.9481050878643362
# differential_evolution step 916: f(x)= 3.9481050878643362
# differential_evolution step 917: f(x)= 3.9481050878643362
# differential_evolution step 918: f(x)= 3.9481050878643362
# differential_evolution step 919: f(x)= 3.9481050878643362
# differential_evolution step 920: f(x)= 3.9481050878643362
# differential_evolution step 921: f(x)= 3.9481050878643362
# differential_evolution step 922: f(x)= 3.9481050878643362
# differential_evolution step 923: f(x)= 3.9481050878643362
# differential_evolution step 924: f(x)= 3.9481050878643362
# differential_evolution step 925: f(x)= 3.9481050878643362
# differential_evolution step 926: f(x)= 3.9481050878643362
# differential_evolution step 927: f(x)= 3.9481050878643362
# differential_evolution step 928: f(x)= 3.9481050878643362
# differential_evolution step 929: f(x)= 3.9481050878643362
# differential_evolution step 930: f(x)= 3.9481050878643362
# differential_evolution step 931: f(x)= 3.9481050878643362
# differential_evolution step 932: f(x)= 3.9481050878643362
# differential_evolution step 933: f(x)= 3.9481050878643362
# differential_evolution step 934: f(x)= 3.9481050878643362
# differential_evolution step 935: f(x)= 3.912937954496409
# differential_evolution step 936: f(x)= 3.912937954496409
# differential_evolution step 937: f(x)= 3.912937954496409
# differential_evolution step 938: f(x)= 3.912937954496409
# differential_evolution step 939: f(x)= 3.912937954496409
# differential_evolution step 940: f(x)= 3.912937954496409
# differential_evolution step 941: f(x)= 3.912937954496409
# differential_evolution step 942: f(x)= 3.912937954496409
# differential_evolution step 943: f(x)= 3.912937954496409
# differential_evolution step 944: f(x)= 3.912937954496409
# differential_evolution step 945: f(x)= 3.912937954496409
# differential_evolution step 946: f(x)= 3.912937954496409
# differential_evolution step 947: f(x)= 3.912937954496409
# differential_evolution step 948: f(x)= 3.912937954496409
# differential_evolution step 949: f(x)= 3.912937954496409
# differential_evolution step 950: f(x)= 3.912937954496409
# differential_evolution step 951: f(x)= 3.912937954496409
# differential_evolution step 952: f(x)= 3.912937954496409
# differential_evolution step 953: f(x)= 3.912937954496409
# differential_evolution step 954: f(x)= 3.912937954496409
# differential_evolution step 955: f(x)= 3.912937954496409
# differential_evolution step 956: f(x)= 3.912937954496409
# differential_evolution step 957: f(x)= 3.912937954496409
# differential_evolution step 958: f(x)= 3.912937954496409
# differential_evolution step 959: f(x)= 3.912937954496409
# differential_evolution step 960: f(x)= 3.912937954496409
# differential_evolution step 961: f(x)= 3.912937954496409
# differential_evolution step 962: f(x)= 3.912937954496409
# differential_evolution step 963: f(x)= 3.912937954496409
# differential_evolution step 964: f(x)= 3.912937954496409
# differential_evolution step 965: f(x)= 3.9115859603592824
# differential_evolution step 966: f(x)= 3.9115859603592824
# differential_evolution step 967: f(x)= 3.9115859603592824
# differential_evolution step 968: f(x)= 3.9115859603592824
# differential_evolution step 969: f(x)= 3.9115859603592824
# differential_evolution step 970: f(x)= 3.9115859603592824
# differential_evolution step 971: f(x)= 3.9115859603592824
# differential_evolution step 972: f(x)= 3.9115859603592824
# differential_evolution step 973: f(x)= 3.9115859603592824
# differential_evolution step 974: f(x)= 3.9115859603592824
# differential_evolution step 975: f(x)= 3.9115859603592824
# differential_evolution step 976: f(x)= 3.9115859603592824
# differential_evolution step 977: f(x)= 3.9115859603592824
# differential_evolution step 978: f(x)= 3.9115859603592824
# differential_evolution step 979: f(x)= 3.9115859603592824
# differential_evolution step 980: f(x)= 3.9115859603592824
# differential_evolution step 981: f(x)= 3.9115859603592824
# differential_evolution step 982: f(x)= 3.9115859603592824
# differential_evolution step 983: f(x)= 3.9115859603592824
# differential_evolution step 984: f(x)= 3.9115859603592824
# differential_evolution step 985: f(x)= 3.9115859603592824
# differential_evolution step 986: f(x)= 3.9115859603592824
# differential_evolution step 987: f(x)= 3.9115859603592824
# differential_evolution step 988: f(x)= 3.9115859603592824
# differential_evolution step 989: f(x)= 3.9115859603592824
# differential_evolution step 990: f(x)= 3.9115859603592824
# differential_evolution step 991: f(x)= 3.9115859603592824
# differential_evolution step 992: f(x)= 3.9115859603592824
# differential_evolution step 993: f(x)= 3.9115859603592824
# differential_evolution step 994: f(x)= 3.9115859603592824
# differential_evolution step 995: f(x)= 3.9115859603592824
# differential_evolution step 996: f(x)= 3.9115859603592824
# differential_evolution step 997: f(x)= 3.9115859603592824
# differential_evolution step 998: f(x)= 3.9115859603592824
# differential_evolution step 999: f(x)= 3.9115859603592824
# differential_evolution step 1000: f(x)= 3.9115859603592824
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.60429009e-02 3.54072970e+01 4.89304058e+00 2.88161984e+01
#  1.65979220e-01 7.89130634e+00 1.72491006e+00 5.70402408e+01
#  9.47377345e-01 5.87932013e+00 3.97801490e-01 7.89626348e+01]
# Chi quadro minimo: 3.8913613573126065

# %%
# Plots:
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\2884650973.py:9: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0146, r_e=38.5665, n=4.8618, x_0=28.8162
# Sérsic 2: I_e=0.1710, r_e=7.7006, n=1.6790, x_0=57.2264
# Sérsic 3: I_e=0.7525, r_e=6.3288, n=0.5351, x_0=78.8740
# [1.06546514e-01 1.74466171e+02 9.60139734e+00 9.88665740e-05
#  1.86454775e-01 5.67720851e+00 8.61855203e-01 2.81797671e-01
#  1.33127295e-01 5.58850007e-01 1.27746161e-01 3.87166238e-01]
# 320.79489976924356
# 348.3811066657953 320.79489976924356 376.05694200110065 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (76, 78),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (81, 83),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 15024.582256106683
# differential_evolution step 2: f(x)= 15024.582256106683
# differential_evolution step 3: f(x)= 4275.626399977332
# differential_evolution step 4: f(x)= 4275.626399977332
# differential_evolution step 5: f(x)= 4275.626399977332
# differential_evolution step 6: f(x)= 211.64564784042554
# differential_evolution step 7: f(x)= 211.64564784042554
# differential_evolution step 8: f(x)= 211.64564784042554
# differential_evolution step 9: f(x)= 211.64564784042554
# differential_evolution step 10: f(x)= 211.64564784042554
# differential_evolution step 11: f(x)= 211.64564784042554
# differential_evolution step 12: f(x)= 211.64564784042554
# differential_evolution step 13: f(x)= 211.64564784042554
# differential_evolution step 14: f(x)= 211.64564784042554
# differential_evolution step 15: f(x)= 211.64564784042554
# differential_evolution step 16: f(x)= 79.63379923469083
# differential_evolution step 17: f(x)= 79.63379923469083
# differential_evolution step 18: f(x)= 60.25548497622797
# differential_evolution step 19: f(x)= 60.25548497622797
# differential_evolution step 20: f(x)= 60.25548497622797
# differential_evolution step 21: f(x)= 60.25548497622797
# differential_evolution step 22: f(x)= 60.25548497622797
# differential_evolution step 23: f(x)= 60.25548497622797
# differential_evolution step 24: f(x)= 60.25548497622797
# differential_evolution step 25: f(x)= 22.53456373470433
# differential_evolution step 26: f(x)= 22.53456373470433
# differential_evolution step 27: f(x)= 22.53456373470433
# differential_evolution step 28: f(x)= 22.53456373470433
# differential_evolution step 29: f(x)= 22.53456373470433
# differential_evolution step 30: f(x)= 22.53456373470433
# differential_evolution step 31: f(x)= 22.53456373470433
# differential_evolution step 32: f(x)= 22.53456373470433
# differential_evolution step 33: f(x)= 22.53456373470433
# differential_evolution step 34: f(x)= 22.53456373470433
# differential_evolution step 35: f(x)= 22.53456373470433
# differential_evolution step 36: f(x)= 22.53456373470433
# differential_evolution step 37: f(x)= 22.53456373470433
# differential_evolution step 38: f(x)= 6.805118394490275
# differential_evolution step 39: f(x)= 6.805118394490275
# differential_evolution step 40: f(x)= 6.805118394490275
# differential_evolution step 41: f(x)= 6.805118394490275
# differential_evolution step 42: f(x)= 6.805118394490275
# differential_evolution step 43: f(x)= 6.805118394490275
# differential_evolution step 44: f(x)= 6.805118394490275
# differential_evolution step 45: f(x)= 6.805118394490275
# differential_evolution step 46: f(x)= 6.805118394490275
# differential_evolution step 47: f(x)= 6.805118394490275
# differential_evolution step 48: f(x)= 6.805118394490275
# differential_evolution step 49: f(x)= 6.805118394490275
# differential_evolution step 50: f(x)= 6.805118394490275
# differential_evolution step 51: f(x)= 6.805118394490275
# differential_evolution step 52: f(x)= 6.805118394490275
# differential_evolution step 53: f(x)= 6.805118394490275
# differential_evolution step 54: f(x)= 6.805118394490275
# differential_evolution step 55: f(x)= 6.805118394490275
# differential_evolution step 56: f(x)= 6.805118394490275
# differential_evolution step 57: f(x)= 6.805118394490275
# differential_evolution step 58: f(x)= 6.738719587419412
# differential_evolution step 59: f(x)= 6.738719587419412
# differential_evolution step 60: f(x)= 6.738719587419412
# differential_evolution step 61: f(x)= 6.738719587419412
# differential_evolution step 62: f(x)= 6.738719587419412
# differential_evolution step 63: f(x)= 6.738719587419412
# differential_evolution step 64: f(x)= 6.738719587419412
# differential_evolution step 65: f(x)= 6.738719587419412
# differential_evolution step 66: f(x)= 6.738719587419412
# differential_evolution step 67: f(x)= 6.738719587419412
# differential_evolution step 68: f(x)= 6.738719587419412
# differential_evolution step 69: f(x)= 6.738719587419412
# differential_evolution step 70: f(x)= 6.738719587419412
# differential_evolution step 71: f(x)= 6.738719587419412
# differential_evolution step 72: f(x)= 6.738719587419412
# differential_evolution step 73: f(x)= 6.738719587419412
# differential_evolution step 74: f(x)= 6.738719587419412
# differential_evolution step 75: f(x)= 6.738719587419412
# differential_evolution step 76: f(x)= 6.487857939470581
# differential_evolution step 77: f(x)= 6.14999672905404
# differential_evolution step 78: f(x)= 6.14999672905404
# differential_evolution step 79: f(x)= 6.14999672905404
# differential_evolution step 80: f(x)= 6.14999672905404
# differential_evolution step 81: f(x)= 6.14999672905404
# differential_evolution step 82: f(x)= 6.14999672905404
# differential_evolution step 83: f(x)= 6.14999672905404
# differential_evolution step 84: f(x)= 6.14999672905404
# differential_evolution step 85: f(x)= 6.14999672905404
# differential_evolution step 86: f(x)= 5.82286751235547
# differential_evolution step 87: f(x)= 5.82286751235547
# differential_evolution step 88: f(x)= 5.82286751235547
# differential_evolution step 89: f(x)= 5.358496618132448
# differential_evolution step 90: f(x)= 5.358496618132448
# differential_evolution step 91: f(x)= 5.358496618132448
# differential_evolution step 92: f(x)= 5.10840208276212
# differential_evolution step 93: f(x)= 5.10840208276212
# differential_evolution step 94: f(x)= 5.10840208276212
# differential_evolution step 95: f(x)= 5.10840208276212
# differential_evolution step 96: f(x)= 5.10840208276212
# differential_evolution step 97: f(x)= 5.10840208276212
# differential_evolution step 98: f(x)= 5.10840208276212
# differential_evolution step 99: f(x)= 5.0139466863816535
# differential_evolution step 100: f(x)= 5.0139466863816535
# differential_evolution step 101: f(x)= 5.0139466863816535
# differential_evolution step 102: f(x)= 5.0139466863816535
# differential_evolution step 103: f(x)= 5.0139466863816535
# differential_evolution step 104: f(x)= 5.0139466863816535
# differential_evolution step 105: f(x)= 5.0139466863816535
# differential_evolution step 106: f(x)= 5.0139466863816535
# differential_evolution step 107: f(x)= 4.880595371032774
# differential_evolution step 108: f(x)= 4.880595371032774
# differential_evolution step 109: f(x)= 4.880595371032774
# differential_evolution step 110: f(x)= 4.880595371032774
# differential_evolution step 111: f(x)= 4.880595371032774
# differential_evolution step 112: f(x)= 4.880595371032774
# differential_evolution step 113: f(x)= 4.542219013726937
# differential_evolution step 114: f(x)= 4.542219013726937
# differential_evolution step 115: f(x)= 4.542219013726937
# differential_evolution step 116: f(x)= 4.542219013726937
# differential_evolution step 117: f(x)= 4.542219013726937
# differential_evolution step 118: f(x)= 4.542219013726937
# differential_evolution step 119: f(x)= 4.542219013726937
# differential_evolution step 120: f(x)= 4.542219013726937
# differential_evolution step 121: f(x)= 4.542219013726937
# differential_evolution step 122: f(x)= 4.542219013726937
# differential_evolution step 123: f(x)= 4.542219013726937
# differential_evolution step 124: f(x)= 4.542219013726937
# differential_evolution step 125: f(x)= 4.542219013726937
# differential_evolution step 126: f(x)= 4.542219013726937
# differential_evolution step 127: f(x)= 4.542219013726937
# differential_evolution step 128: f(x)= 4.474268407028802
# differential_evolution step 129: f(x)= 4.474268407028802
# differential_evolution step 130: f(x)= 4.474268407028802
# differential_evolution step 131: f(x)= 4.474268407028802
# differential_evolution step 132: f(x)= 4.474268407028802
# differential_evolution step 133: f(x)= 4.474268407028802
# differential_evolution step 134: f(x)= 4.474268407028802
# differential_evolution step 135: f(x)= 4.474268407028802
# differential_evolution step 136: f(x)= 4.474268407028802
# differential_evolution step 137: f(x)= 4.474268407028802
# differential_evolution step 138: f(x)= 4.474268407028802
# differential_evolution step 139: f(x)= 4.474268407028802
# differential_evolution step 140: f(x)= 4.474268407028802
# differential_evolution step 141: f(x)= 4.432588943596483
# differential_evolution step 142: f(x)= 4.432588943596483
# differential_evolution step 143: f(x)= 4.432588943596483
# differential_evolution step 144: f(x)= 4.162401944869058
# differential_evolution step 145: f(x)= 4.162401944869058
# differential_evolution step 146: f(x)= 4.162401944869058
# differential_evolution step 147: f(x)= 4.162401944869058
# differential_evolution step 148: f(x)= 4.162401944869058
# differential_evolution step 149: f(x)= 4.162401944869058
# differential_evolution step 150: f(x)= 4.162401944869058
# differential_evolution step 151: f(x)= 4.162401944869058
# differential_evolution step 152: f(x)= 4.162401944869058
# differential_evolution step 153: f(x)= 4.162401944869058
# differential_evolution step 154: f(x)= 4.162401944869058
# differential_evolution step 155: f(x)= 4.162401944869058
# differential_evolution step 156: f(x)= 4.162401944869058
# differential_evolution step 157: f(x)= 4.162401944869058
# differential_evolution step 158: f(x)= 4.162401944869058
# differential_evolution step 159: f(x)= 4.162401944869058
# differential_evolution step 160: f(x)= 4.162401944869058
# differential_evolution step 161: f(x)= 4.162401944869058
# differential_evolution step 162: f(x)= 4.042906304898726
# differential_evolution step 163: f(x)= 4.042906304898726
# differential_evolution step 164: f(x)= 4.042906304898726
# differential_evolution step 165: f(x)= 4.042906304898726
# differential_evolution step 166: f(x)= 4.042906304898726
# differential_evolution step 167: f(x)= 4.042906304898726
# differential_evolution step 168: f(x)= 4.042906304898726
# differential_evolution step 169: f(x)= 4.042906304898726
# differential_evolution step 170: f(x)= 4.042906304898726
# differential_evolution step 171: f(x)= 4.042906304898726
# differential_evolution step 172: f(x)= 4.042906304898726
# differential_evolution step 173: f(x)= 4.042906304898726
# differential_evolution step 174: f(x)= 4.042906304898726
# differential_evolution step 175: f(x)= 4.042906304898726
# differential_evolution step 176: f(x)= 4.042906304898726
# differential_evolution step 177: f(x)= 4.042906304898726
# differential_evolution step 178: f(x)= 3.9439281375624042
# differential_evolution step 179: f(x)= 3.9439281375624042
# differential_evolution step 180: f(x)= 3.9439281375624042
# differential_evolution step 181: f(x)= 3.9144352342373434
# differential_evolution step 182: f(x)= 3.825309864547237
# differential_evolution step 183: f(x)= 3.825309864547237
# differential_evolution step 184: f(x)= 3.825309864547237
# differential_evolution step 185: f(x)= 3.825309864547237
# differential_evolution step 186: f(x)= 3.825309864547237
# differential_evolution step 187: f(x)= 3.7377847899192846
# differential_evolution step 188: f(x)= 3.7377847899192846
# differential_evolution step 189: f(x)= 3.7377847899192846
# differential_evolution step 190: f(x)= 3.7377847899192846
# differential_evolution step 191: f(x)= 3.7377847899192846
# differential_evolution step 192: f(x)= 3.7377847899192846
# differential_evolution step 193: f(x)= 3.7377847899192846
# differential_evolution step 194: f(x)= 3.7377847899192846
# differential_evolution step 195: f(x)= 3.7377847899192846
# differential_evolution step 196: f(x)= 3.7377847899192846
# differential_evolution step 197: f(x)= 3.7377847899192846
# differential_evolution step 198: f(x)= 3.7377847899192846
# differential_evolution step 199: f(x)= 3.7377847899192846
# differential_evolution step 200: f(x)= 3.7377847899192846
# differential_evolution step 201: f(x)= 3.7377847899192846
# differential_evolution step 202: f(x)= 3.7377847899192846
# differential_evolution step 203: f(x)= 3.7377847899192846
# differential_evolution step 204: f(x)= 3.7377847899192846
# differential_evolution step 205: f(x)= 3.7377847899192846
# differential_evolution step 206: f(x)= 3.6527351201035487
# differential_evolution step 207: f(x)= 3.6527351201035487
# differential_evolution step 208: f(x)= 3.6527351201035487
# differential_evolution step 209: f(x)= 3.6527351201035487
# differential_evolution step 210: f(x)= 3.6527351201035487
# differential_evolution step 211: f(x)= 3.6527351201035487
# differential_evolution step 212: f(x)= 3.6527351201035487
# differential_evolution step 213: f(x)= 3.6527351201035487
# differential_evolution step 214: f(x)= 3.6527351201035487
# differential_evolution step 215: f(x)= 3.6527351201035487
# differential_evolution step 216: f(x)= 3.6527351201035487
# differential_evolution step 217: f(x)= 3.6527351201035487
# differential_evolution step 218: f(x)= 3.6527351201035487
# differential_evolution step 219: f(x)= 3.6527351201035487
# differential_evolution step 220: f(x)= 3.6527351201035487
# differential_evolution step 221: f(x)= 3.647953392573985
# differential_evolution step 222: f(x)= 3.647953392573985
# differential_evolution step 223: f(x)= 3.647953392573985
# differential_evolution step 224: f(x)= 3.626893187319168
# differential_evolution step 225: f(x)= 3.5885006120404905
# differential_evolution step 226: f(x)= 3.5885006120404905
# differential_evolution step 227: f(x)= 3.5885006120404905
# differential_evolution step 228: f(x)= 3.5885006120404905
# differential_evolution step 229: f(x)= 3.5885006120404905
# differential_evolution step 230: f(x)= 3.5885006120404905
# differential_evolution step 231: f(x)= 3.5885006120404905
# differential_evolution step 232: f(x)= 3.5885006120404905
# differential_evolution step 233: f(x)= 3.5885006120404905
# differential_evolution step 234: f(x)= 3.549285845288903
# differential_evolution step 235: f(x)= 3.549285845288903
# differential_evolution step 236: f(x)= 3.549285845288903
# differential_evolution step 237: f(x)= 3.527473025824162
# differential_evolution step 238: f(x)= 3.5273198735252125
# differential_evolution step 239: f(x)= 3.5273198735252125
# differential_evolution step 240: f(x)= 3.5273198735252125
# differential_evolution step 241: f(x)= 3.5273198735252125
# differential_evolution step 242: f(x)= 3.5273198735252125
# differential_evolution step 243: f(x)= 3.5273198735252125
# differential_evolution step 244: f(x)= 3.5273198735252125
# differential_evolution step 245: f(x)= 3.5273198735252125
# differential_evolution step 246: f(x)= 3.5273198735252125
# differential_evolution step 247: f(x)= 3.5273198735252125
# differential_evolution step 248: f(x)= 3.5273198735252125
# differential_evolution step 249: f(x)= 3.5273198735252125
# differential_evolution step 250: f(x)= 3.4913174348585727
# differential_evolution step 251: f(x)= 3.486512182420538
# differential_evolution step 252: f(x)= 3.486512182420538
# differential_evolution step 253: f(x)= 3.486512182420538
# differential_evolution step 254: f(x)= 3.486512182420538
# differential_evolution step 255: f(x)= 3.486512182420538
# differential_evolution step 256: f(x)= 3.486512182420538
# differential_evolution step 257: f(x)= 3.486512182420538
# differential_evolution step 258: f(x)= 3.486512182420538
# differential_evolution step 259: f(x)= 3.486512182420538
# differential_evolution step 260: f(x)= 3.486512182420538
# differential_evolution step 261: f(x)= 3.486512182420538
# differential_evolution step 262: f(x)= 3.486512182420538
# differential_evolution step 263: f(x)= 3.486512182420538
# differential_evolution step 264: f(x)= 3.486512182420538
# differential_evolution step 265: f(x)= 3.486512182420538
# differential_evolution step 266: f(x)= 3.486512182420538
# differential_evolution step 267: f(x)= 3.486512182420538
# differential_evolution step 268: f(x)= 3.486512182420538
# differential_evolution step 269: f(x)= 3.48500147503126
# differential_evolution step 270: f(x)= 3.4802421644246033
# differential_evolution step 271: f(x)= 3.4802421644246033
# differential_evolution step 272: f(x)= 3.4802421644246033
# differential_evolution step 273: f(x)= 3.4539812205406126
# differential_evolution step 274: f(x)= 3.4539812205406126
# differential_evolution step 275: f(x)= 3.4539812205406126
# differential_evolution step 276: f(x)= 3.4539812205406126
# differential_evolution step 277: f(x)= 3.4539812205406126
# differential_evolution step 278: f(x)= 3.4539812205406126
# differential_evolution step 279: f(x)= 3.4539812205406126
# differential_evolution step 280: f(x)= 3.4539812205406126
# differential_evolution step 281: f(x)= 3.4539812205406126
# differential_evolution step 282: f(x)= 3.4539812205406126
# differential_evolution step 283: f(x)= 3.4539812205406126
# differential_evolution step 284: f(x)= 3.4539812205406126
# differential_evolution step 285: f(x)= 3.4539812205406126
# differential_evolution step 286: f(x)= 3.4539812205406126
# differential_evolution step 287: f(x)= 3.4539812205406126
# differential_evolution step 288: f(x)= 3.4539812205406126
# differential_evolution step 289: f(x)= 3.4539812205406126
# differential_evolution step 290: f(x)= 3.451688142452314
# differential_evolution step 291: f(x)= 3.451688142452314
# differential_evolution step 292: f(x)= 3.451688142452314
# differential_evolution step 293: f(x)= 3.4514872150205904
# differential_evolution step 294: f(x)= 3.4514872150205904
# differential_evolution step 295: f(x)= 3.4514872150205904
# differential_evolution step 296: f(x)= 3.4514872150205904
# differential_evolution step 297: f(x)= 3.412579169160391
# differential_evolution step 298: f(x)= 3.412579169160391
# differential_evolution step 299: f(x)= 3.412579169160391
# differential_evolution step 300: f(x)= 3.412579169160391
# differential_evolution step 301: f(x)= 3.412579169160391
# differential_evolution step 302: f(x)= 3.412579169160391
# differential_evolution step 303: f(x)= 3.412579169160391
# differential_evolution step 304: f(x)= 3.412579169160391
# differential_evolution step 305: f(x)= 3.412579169160391
# differential_evolution step 306: f(x)= 3.412579169160391
# differential_evolution step 307: f(x)= 3.412579169160391
# differential_evolution step 308: f(x)= 3.403069925239444
# differential_evolution step 309: f(x)= 3.403069925239444
# differential_evolution step 310: f(x)= 3.403069925239444
# differential_evolution step 311: f(x)= 3.403069925239444
# differential_evolution step 312: f(x)= 3.3795439409687376
# differential_evolution step 313: f(x)= 3.3795439409687376
# differential_evolution step 314: f(x)= 3.3795439409687376
# differential_evolution step 315: f(x)= 3.3795439409687376
# differential_evolution step 316: f(x)= 3.3699382054260405
# differential_evolution step 317: f(x)= 3.3699382054260405
# differential_evolution step 318: f(x)= 3.3699382054260405
# differential_evolution step 319: f(x)= 3.3699382054260405
# differential_evolution step 320: f(x)= 3.3699382054260405
# differential_evolution step 321: f(x)= 3.3699382054260405
# differential_evolution step 322: f(x)= 3.3699382054260405
# differential_evolution step 323: f(x)= 3.3699382054260405
# differential_evolution step 324: f(x)= 3.3699382054260405
# differential_evolution step 325: f(x)= 3.3699382054260405
# differential_evolution step 326: f(x)= 3.369194004774713
# differential_evolution step 327: f(x)= 3.369194004774713
# differential_evolution step 328: f(x)= 3.369194004774713
# differential_evolution step 329: f(x)= 3.369194004774713
# differential_evolution step 330: f(x)= 3.369194004774713
# differential_evolution step 331: f(x)= 3.369194004774713
# differential_evolution step 332: f(x)= 3.369194004774713
# differential_evolution step 333: f(x)= 3.349961384076581
# differential_evolution step 334: f(x)= 3.349961384076581
# differential_evolution step 335: f(x)= 3.349961384076581
# differential_evolution step 336: f(x)= 3.349961384076581
# differential_evolution step 337: f(x)= 3.349961384076581
# differential_evolution step 338: f(x)= 3.349961384076581
# differential_evolution step 339: f(x)= 3.349961384076581
# differential_evolution step 340: f(x)= 3.349961384076581
# differential_evolution step 341: f(x)= 3.349961384076581
# differential_evolution step 342: f(x)= 3.349961384076581
# differential_evolution step 343: f(x)= 3.349961384076581
# differential_evolution step 344: f(x)= 3.349961384076581
# differential_evolution step 345: f(x)= 3.349961384076581
# differential_evolution step 346: f(x)= 3.349961384076581
# differential_evolution step 347: f(x)= 3.349961384076581
# differential_evolution step 348: f(x)= 3.349961384076581
# differential_evolution step 349: f(x)= 3.3194010444503737
# differential_evolution step 350: f(x)= 3.3194010444503737
# differential_evolution step 351: f(x)= 3.3194010444503737
# differential_evolution step 352: f(x)= 3.3194010444503737
# differential_evolution step 353: f(x)= 3.3194010444503737
# differential_evolution step 354: f(x)= 3.3194010444503737
# differential_evolution step 355: f(x)= 3.3194010444503737
# differential_evolution step 356: f(x)= 3.3194010444503737
# differential_evolution step 357: f(x)= 3.3194010444503737
# differential_evolution step 358: f(x)= 3.3194010444503737
# differential_evolution step 359: f(x)= 3.3194010444503737
# differential_evolution step 360: f(x)= 3.306220389868948
# differential_evolution step 361: f(x)= 3.306220389868948
# differential_evolution step 362: f(x)= 3.306220389868948
# differential_evolution step 363: f(x)= 3.306220389868948
# differential_evolution step 364: f(x)= 3.306220389868948
# differential_evolution step 365: f(x)= 3.306220389868948
# differential_evolution step 366: f(x)= 3.306220389868948
# differential_evolution step 367: f(x)= 3.306220389868948
# differential_evolution step 368: f(x)= 3.306220389868948
# differential_evolution step 369: f(x)= 3.306220389868948
# differential_evolution step 370: f(x)= 3.306220389868948
# differential_evolution step 371: f(x)= 3.306220389868948
# differential_evolution step 372: f(x)= 3.306220389868948
# differential_evolution step 373: f(x)= 3.306220389868948
# differential_evolution step 374: f(x)= 3.306220389868948
# differential_evolution step 375: f(x)= 3.306220389868948
# differential_evolution step 376: f(x)= 3.306220389868948
# differential_evolution step 377: f(x)= 3.306220389868948
# differential_evolution step 378: f(x)= 3.306220389868948
# differential_evolution step 379: f(x)= 3.306220389868948
# differential_evolution step 380: f(x)= 3.306220389868948
# differential_evolution step 381: f(x)= 3.306220389868948
# differential_evolution step 382: f(x)= 3.306220389868948
# differential_evolution step 383: f(x)= 3.306220389868948
# differential_evolution step 384: f(x)= 3.306220389868948
# differential_evolution step 385: f(x)= 3.306220389868948
# differential_evolution step 386: f(x)= 3.306220389868948
# differential_evolution step 387: f(x)= 3.306220389868948
# differential_evolution step 388: f(x)= 3.306220389868948
# differential_evolution step 389: f(x)= 3.306220389868948
# differential_evolution step 390: f(x)= 3.306220389868948
# differential_evolution step 391: f(x)= 3.306220389868948
# differential_evolution step 392: f(x)= 3.306220389868948
# differential_evolution step 393: f(x)= 3.306220389868948
# differential_evolution step 394: f(x)= 3.306220389868948
# differential_evolution step 395: f(x)= 3.306220389868948
# differential_evolution step 396: f(x)= 3.306220389868948
# differential_evolution step 397: f(x)= 3.306220389868948
# differential_evolution step 398: f(x)= 3.306220389868948
# differential_evolution step 399: f(x)= 3.306220389868948
# differential_evolution step 400: f(x)= 3.306220389868948
# differential_evolution step 401: f(x)= 3.306220389868948
# differential_evolution step 402: f(x)= 3.306220389868948
# differential_evolution step 403: f(x)= 3.306220389868948
# differential_evolution step 404: f(x)= 3.306220389868948
# differential_evolution step 405: f(x)= 3.306220389868948
# differential_evolution step 406: f(x)= 3.306220389868948
# differential_evolution step 407: f(x)= 3.306220389868948
# differential_evolution step 408: f(x)= 3.306220389868948
# differential_evolution step 409: f(x)= 3.306220389868948
# differential_evolution step 410: f(x)= 3.306220389868948
# differential_evolution step 411: f(x)= 3.306220389868948
# differential_evolution step 412: f(x)= 3.306220389868948
# differential_evolution step 413: f(x)= 3.306220389868948
# differential_evolution step 414: f(x)= 3.306220389868948
# differential_evolution step 415: f(x)= 3.306220389868948
# differential_evolution step 416: f(x)= 3.306220389868948
# differential_evolution step 417: f(x)= 3.306220389868948
# differential_evolution step 418: f(x)= 3.306220389868948
# differential_evolution step 419: f(x)= 3.306220389868948
# differential_evolution step 420: f(x)= 3.306220389868948
# differential_evolution step 421: f(x)= 3.306220389868948
# differential_evolution step 422: f(x)= 3.306220389868948
# differential_evolution step 423: f(x)= 3.306220389868948
# differential_evolution step 424: f(x)= 3.28448793920616
# differential_evolution step 425: f(x)= 3.28448793920616
# differential_evolution step 426: f(x)= 3.28448793920616
# differential_evolution step 427: f(x)= 3.28448793920616
# differential_evolution step 428: f(x)= 3.28448793920616
# differential_evolution step 429: f(x)= 3.28448793920616
# differential_evolution step 430: f(x)= 3.28448793920616
# differential_evolution step 431: f(x)= 3.28448793920616
# differential_evolution step 432: f(x)= 3.28448793920616
# differential_evolution step 433: f(x)= 3.28448793920616
# differential_evolution step 434: f(x)= 3.28448793920616
# differential_evolution step 435: f(x)= 3.28448793920616
# differential_evolution step 436: f(x)= 3.28448793920616
# differential_evolution step 437: f(x)= 3.28448793920616
# differential_evolution step 438: f(x)= 3.28448793920616
# differential_evolution step 439: f(x)= 3.28448793920616
# differential_evolution step 440: f(x)= 3.28448793920616
# differential_evolution step 441: f(x)= 3.28448793920616
# differential_evolution step 442: f(x)= 3.28448793920616
# differential_evolution step 443: f(x)= 3.28448793920616
# differential_evolution step 444: f(x)= 3.28448793920616
# differential_evolution step 445: f(x)= 3.28448793920616
# differential_evolution step 446: f(x)= 3.28448793920616
# differential_evolution step 447: f(x)= 3.28448793920616
# differential_evolution step 448: f(x)= 3.28448793920616
# differential_evolution step 449: f(x)= 3.28448793920616
# differential_evolution step 450: f(x)= 3.28448793920616
# differential_evolution step 451: f(x)= 3.28448793920616
# differential_evolution step 452: f(x)= 3.263379125207066
# differential_evolution step 453: f(x)= 3.263379125207066
# differential_evolution step 454: f(x)= 3.263379125207066
# differential_evolution step 455: f(x)= 3.263379125207066
# differential_evolution step 456: f(x)= 3.263379125207066
# differential_evolution step 457: f(x)= 3.263379125207066
# differential_evolution step 458: f(x)= 3.263379125207066
# differential_evolution step 459: f(x)= 3.263379125207066
# differential_evolution step 460: f(x)= 3.25960851558104
# differential_evolution step 461: f(x)= 3.25960851558104
# differential_evolution step 462: f(x)= 3.25960851558104
# differential_evolution step 463: f(x)= 3.25960851558104
# differential_evolution step 464: f(x)= 3.25960851558104
# differential_evolution step 465: f(x)= 3.25960851558104
# differential_evolution step 466: f(x)= 3.25960851558104
# differential_evolution step 467: f(x)= 3.25960851558104
# differential_evolution step 468: f(x)= 3.25960851558104
# differential_evolution step 469: f(x)= 3.25960851558104
# differential_evolution step 470: f(x)= 3.25960851558104
# differential_evolution step 471: f(x)= 3.25960851558104
# differential_evolution step 472: f(x)= 3.25960851558104
# differential_evolution step 473: f(x)= 3.25960851558104
# differential_evolution step 474: f(x)= 3.25960851558104
# differential_evolution step 475: f(x)= 3.25960851558104
# differential_evolution step 476: f(x)= 3.25960851558104
# differential_evolution step 477: f(x)= 3.2524495481574007
# differential_evolution step 478: f(x)= 3.247161444555178
# differential_evolution step 479: f(x)= 3.247161444555178
# differential_evolution step 480: f(x)= 3.247161444555178
# differential_evolution step 481: f(x)= 3.247161444555178
# differential_evolution step 482: f(x)= 3.247161444555178
# differential_evolution step 483: f(x)= 3.247161444555178
# differential_evolution step 484: f(x)= 3.247161444555178
# differential_evolution step 485: f(x)= 3.247161444555178
# differential_evolution step 486: f(x)= 3.247161444555178
# differential_evolution step 487: f(x)= 3.247161444555178
# differential_evolution step 488: f(x)= 3.247161444555178
# differential_evolution step 489: f(x)= 3.247161444555178
# differential_evolution step 490: f(x)= 3.247161444555178
# differential_evolution step 491: f(x)= 3.247161444555178
# differential_evolution step 492: f(x)= 3.247161444555178
# differential_evolution step 493: f(x)= 3.247161444555178
# differential_evolution step 494: f(x)= 3.247161444555178
# differential_evolution step 495: f(x)= 3.2439209324181437
# differential_evolution step 496: f(x)= 3.2439209324181437
# differential_evolution step 497: f(x)= 3.2439209324181437
# differential_evolution step 498: f(x)= 3.2439209324181437
# differential_evolution step 499: f(x)= 3.2439209324181437
# differential_evolution step 500: f(x)= 3.2439209324181437
# differential_evolution step 501: f(x)= 3.2439209324181437
# differential_evolution step 502: f(x)= 3.2439209324181437
# differential_evolution step 503: f(x)= 3.2439209324181437
# differential_evolution step 504: f(x)= 3.2439209324181437
# differential_evolution step 505: f(x)= 3.2439209324181437
# differential_evolution step 506: f(x)= 3.2439209324181437
# differential_evolution step 507: f(x)= 3.2439209324181437
# differential_evolution step 508: f(x)= 3.2439209324181437
# differential_evolution step 509: f(x)= 3.2439209324181437
# differential_evolution step 510: f(x)= 3.2439209324181437
# differential_evolution step 511: f(x)= 3.2439209324181437
# differential_evolution step 512: f(x)= 3.233402737814792
# differential_evolution step 513: f(x)= 3.233402737814792
# differential_evolution step 514: f(x)= 3.233402737814792
# differential_evolution step 515: f(x)= 3.233402737814792
# differential_evolution step 516: f(x)= 3.233402737814792
# differential_evolution step 517: f(x)= 3.233402737814792
# differential_evolution step 518: f(x)= 3.233402737814792
# differential_evolution step 519: f(x)= 3.233402737814792
# differential_evolution step 520: f(x)= 3.233402737814792
# differential_evolution step 521: f(x)= 3.233402737814792
# differential_evolution step 522: f(x)= 3.233402737814792
# differential_evolution step 523: f(x)= 3.233402737814792
# differential_evolution step 524: f(x)= 3.233402737814792
# differential_evolution step 525: f(x)= 3.233402737814792
# differential_evolution step 526: f(x)= 3.233402737814792
# differential_evolution step 527: f(x)= 3.233402737814792
# differential_evolution step 528: f(x)= 3.233402737814792
# differential_evolution step 529: f(x)= 3.233402737814792
# differential_evolution step 530: f(x)= 3.233402737814792
# differential_evolution step 531: f(x)= 3.233402737814792
# differential_evolution step 532: f(x)= 3.233402737814792
# differential_evolution step 533: f(x)= 3.233402737814792
# differential_evolution step 534: f(x)= 3.233402737814792
# differential_evolution step 535: f(x)= 3.233402737814792
# differential_evolution step 536: f(x)= 3.233402737814792
# differential_evolution step 537: f(x)= 3.233402737814792
# differential_evolution step 538: f(x)= 3.233402737814792
# differential_evolution step 539: f(x)= 3.233402737814792
# differential_evolution step 540: f(x)= 3.2186768837285684
# differential_evolution step 541: f(x)= 3.2186768837285684
# differential_evolution step 542: f(x)= 3.2186768837285684
# differential_evolution step 543: f(x)= 3.2186768837285684
# differential_evolution step 544: f(x)= 3.2186768837285684
# differential_evolution step 545: f(x)= 3.201191836770567
# differential_evolution step 546: f(x)= 3.201191836770567
# differential_evolution step 547: f(x)= 3.201191836770567
# differential_evolution step 548: f(x)= 3.201191836770567
# differential_evolution step 549: f(x)= 3.201191836770567
# differential_evolution step 550: f(x)= 3.201191836770567
# differential_evolution step 551: f(x)= 3.201191836770567
# differential_evolution step 552: f(x)= 3.1966590877398726
# differential_evolution step 553: f(x)= 3.1966590877398726
# differential_evolution step 554: f(x)= 3.1966590877398726
# differential_evolution step 555: f(x)= 3.1966590877398726
# differential_evolution step 556: f(x)= 3.1966590877398726
# differential_evolution step 557: f(x)= 3.1966590877398726
# differential_evolution step 558: f(x)= 3.1966590877398726
# differential_evolution step 559: f(x)= 3.1966590877398726
# differential_evolution step 560: f(x)= 3.193577218277782
# differential_evolution step 561: f(x)= 3.193577218277782
# differential_evolution step 562: f(x)= 3.193577218277782
# differential_evolution step 563: f(x)= 3.193577218277782
# differential_evolution step 564: f(x)= 3.193577218277782
# differential_evolution step 565: f(x)= 3.193577218277782
# differential_evolution step 566: f(x)= 3.193577218277782
# differential_evolution step 567: f(x)= 3.193577218277782
# differential_evolution step 568: f(x)= 3.193577218277782
# differential_evolution step 569: f(x)= 3.193577218277782
# differential_evolution step 570: f(x)= 3.193577218277782
# differential_evolution step 571: f(x)= 3.193577218277782
# differential_evolution step 572: f(x)= 3.193577218277782
# differential_evolution step 573: f(x)= 3.1671575278502053
# differential_evolution step 574: f(x)= 3.1671575278502053
# differential_evolution step 575: f(x)= 3.1671575278502053
# differential_evolution step 576: f(x)= 3.1671575278502053
# differential_evolution step 577: f(x)= 3.1671575278502053
# differential_evolution step 578: f(x)= 3.1671575278502053
# differential_evolution step 579: f(x)= 3.1671575278502053
# differential_evolution step 580: f(x)= 3.1671575278502053
# differential_evolution step 581: f(x)= 3.1671575278502053
# differential_evolution step 582: f(x)= 3.1671575278502053
# differential_evolution step 583: f(x)= 3.1671575278502053
# differential_evolution step 584: f(x)= 3.1671575278502053
# differential_evolution step 585: f(x)= 3.1671575278502053
# differential_evolution step 586: f(x)= 3.1671575278502053
# differential_evolution step 587: f(x)= 3.1671575278502053
# differential_evolution step 588: f(x)= 3.1671575278502053
# differential_evolution step 589: f(x)= 3.1671575278502053
# differential_evolution step 590: f(x)= 3.1671575278502053
# differential_evolution step 591: f(x)= 3.1671575278502053
# differential_evolution step 592: f(x)= 3.1671575278502053
# differential_evolution step 593: f(x)= 3.1671575278502053
# differential_evolution step 594: f(x)= 3.1671575278502053
# differential_evolution step 595: f(x)= 3.1671575278502053
# differential_evolution step 596: f(x)= 3.1671575278502053
# differential_evolution step 597: f(x)= 3.1671575278502053
# differential_evolution step 598: f(x)= 3.1671575278502053
# differential_evolution step 599: f(x)= 3.1671575278502053
# differential_evolution step 600: f(x)= 3.1671575278502053
# differential_evolution step 601: f(x)= 3.1671575278502053
# differential_evolution step 602: f(x)= 3.1671575278502053
# differential_evolution step 603: f(x)= 3.1671575278502053
# differential_evolution step 604: f(x)= 3.1671575278502053
# differential_evolution step 605: f(x)= 3.1671575278502053
# differential_evolution step 606: f(x)= 3.1671575278502053
# differential_evolution step 607: f(x)= 3.1671575278502053
# differential_evolution step 608: f(x)= 3.1671575278502053
# differential_evolution step 609: f(x)= 3.1671575278502053
# differential_evolution step 610: f(x)= 3.1671575278502053
# differential_evolution step 611: f(x)= 3.1671575278502053
# differential_evolution step 612: f(x)= 3.1671575278502053
# differential_evolution step 613: f(x)= 3.1671575278502053
# differential_evolution step 614: f(x)= 3.1671575278502053
# differential_evolution step 615: f(x)= 3.1671575278502053
# differential_evolution step 616: f(x)= 3.1492752944581075
# differential_evolution step 617: f(x)= 3.1492752944581075
# differential_evolution step 618: f(x)= 3.1492752944581075
# differential_evolution step 619: f(x)= 3.1492752944581075
# differential_evolution step 620: f(x)= 3.1421039491385843
# differential_evolution step 621: f(x)= 3.1421039491385843
# differential_evolution step 622: f(x)= 3.1421039491385843
# differential_evolution step 623: f(x)= 3.1421039491385843
# differential_evolution step 624: f(x)= 3.1421039491385843
# differential_evolution step 625: f(x)= 3.1421039491385843
# differential_evolution step 626: f(x)= 3.1421039491385843
# differential_evolution step 627: f(x)= 3.1421039491385843
# differential_evolution step 628: f(x)= 3.1421039491385843
# differential_evolution step 629: f(x)= 3.1421039491385843
# differential_evolution step 630: f(x)= 3.1421039491385843
# differential_evolution step 631: f(x)= 3.1421039491385843
# differential_evolution step 632: f(x)= 3.1421039491385843
# differential_evolution step 633: f(x)= 3.1419461160583313
# differential_evolution step 634: f(x)= 3.1419461160583313
# differential_evolution step 635: f(x)= 3.1419461160583313
# differential_evolution step 636: f(x)= 3.1419461160583313
# differential_evolution step 637: f(x)= 3.1419461160583313
# differential_evolution step 638: f(x)= 3.1267051462122577
# differential_evolution step 639: f(x)= 3.1267051462122577
# differential_evolution step 640: f(x)= 3.1267051462122577
# differential_evolution step 641: f(x)= 3.1267051462122577
# differential_evolution step 642: f(x)= 3.1267051462122577
# differential_evolution step 643: f(x)= 3.1267051462122577
# differential_evolution step 644: f(x)= 3.1267051462122577
# differential_evolution step 645: f(x)= 3.1267051462122577
# differential_evolution step 646: f(x)= 3.1267051462122577
# differential_evolution step 647: f(x)= 3.1267051462122577
# differential_evolution step 648: f(x)= 3.1267051462122577
# differential_evolution step 649: f(x)= 3.1267051462122577
# differential_evolution step 650: f(x)= 3.1267051462122577
# differential_evolution step 651: f(x)= 3.109876898647874
# differential_evolution step 652: f(x)= 3.103886333871076
# differential_evolution step 653: f(x)= 3.103886333871076
# differential_evolution step 654: f(x)= 3.103886333871076
# differential_evolution step 655: f(x)= 3.103886333871076
# differential_evolution step 656: f(x)= 3.103886333871076
# differential_evolution step 657: f(x)= 3.103886333871076
# differential_evolution step 658: f(x)= 3.103886333871076
# differential_evolution step 659: f(x)= 3.103886333871076
# differential_evolution step 660: f(x)= 3.103886333871076
# differential_evolution step 661: f(x)= 3.103886333871076
# differential_evolution step 662: f(x)= 3.103886333871076
# differential_evolution step 663: f(x)= 3.103886333871076
# differential_evolution step 664: f(x)= 3.103886333871076
# differential_evolution step 665: f(x)= 3.103886333871076
# differential_evolution step 666: f(x)= 3.103886333871076
# differential_evolution step 667: f(x)= 3.103886333871076
# differential_evolution step 668: f(x)= 3.103886333871076
# differential_evolution step 669: f(x)= 3.103886333871076
# differential_evolution step 670: f(x)= 3.103886333871076
# differential_evolution step 671: f(x)= 3.103886333871076
# differential_evolution step 672: f(x)= 3.103886333871076
# differential_evolution step 673: f(x)= 3.103886333871076
# differential_evolution step 674: f(x)= 3.103886333871076
# differential_evolution step 675: f(x)= 3.103886333871076
# differential_evolution step 676: f(x)= 3.103886333871076
# differential_evolution step 677: f(x)= 3.103886333871076
# differential_evolution step 678: f(x)= 3.103886333871076
# differential_evolution step 679: f(x)= 3.103886333871076
# differential_evolution step 680: f(x)= 3.103886333871076
# differential_evolution step 681: f(x)= 3.103886333871076
# differential_evolution step 682: f(x)= 3.103886333871076
# differential_evolution step 683: f(x)= 3.103886333871076
# differential_evolution step 684: f(x)= 3.103886333871076
# differential_evolution step 685: f(x)= 3.103886333871076
# differential_evolution step 686: f(x)= 3.103886333871076
# differential_evolution step 687: f(x)= 3.103886333871076
# differential_evolution step 688: f(x)= 3.103886333871076
# differential_evolution step 689: f(x)= 3.103886333871076
# differential_evolution step 690: f(x)= 3.103886333871076
# differential_evolution step 691: f(x)= 3.103886333871076
# differential_evolution step 692: f(x)= 3.103886333871076
# differential_evolution step 693: f(x)= 3.087478705293866
# differential_evolution step 694: f(x)= 3.087478705293866
# differential_evolution step 695: f(x)= 3.087478705293866
# differential_evolution step 696: f(x)= 3.087478705293866
# differential_evolution step 697: f(x)= 3.087478705293866
# differential_evolution step 698: f(x)= 3.0833702496134303
# differential_evolution step 699: f(x)= 3.0833702496134303
# differential_evolution step 700: f(x)= 3.0833702496134303
# differential_evolution step 701: f(x)= 3.0833702496134303
# differential_evolution step 702: f(x)= 3.0833702496134303
# differential_evolution step 703: f(x)= 3.0833702496134303
# differential_evolution step 704: f(x)= 3.0833702496134303
# differential_evolution step 705: f(x)= 3.0833702496134303
# differential_evolution step 706: f(x)= 3.0833702496134303
# differential_evolution step 707: f(x)= 3.0833702496134303
# differential_evolution step 708: f(x)= 3.078912388710363
# differential_evolution step 709: f(x)= 3.078912388710363
# differential_evolution step 710: f(x)= 3.078912388710363
# differential_evolution step 711: f(x)= 3.072061011243857
# differential_evolution step 712: f(x)= 3.072061011243857
# differential_evolution step 713: f(x)= 3.072061011243857
# differential_evolution step 714: f(x)= 3.072061011243857
# differential_evolution step 715: f(x)= 3.072061011243857
# differential_evolution step 716: f(x)= 3.0653783150506744
# differential_evolution step 717: f(x)= 3.0653783150506744
# differential_evolution step 718: f(x)= 3.0653783150506744
# differential_evolution step 719: f(x)= 3.0653783150506744
# differential_evolution step 720: f(x)= 3.0653783150506744
# differential_evolution step 721: f(x)= 3.0653783150506744
# differential_evolution step 722: f(x)= 3.0653783150506744
# differential_evolution step 723: f(x)= 3.0653783150506744
# differential_evolution step 724: f(x)= 3.0653783150506744
# differential_evolution step 725: f(x)= 3.0653783150506744
# differential_evolution step 726: f(x)= 3.0653783150506744
# differential_evolution step 727: f(x)= 3.0653783150506744
# differential_evolution step 728: f(x)= 3.0653783150506744
# differential_evolution step 729: f(x)= 3.0653783150506744
# differential_evolution step 730: f(x)= 3.0653783150506744
# differential_evolution step 731: f(x)= 3.0653783150506744
# differential_evolution step 732: f(x)= 3.0653783150506744
# differential_evolution step 733: f(x)= 3.0653783150506744
# differential_evolution step 734: f(x)= 3.0653783150506744
# differential_evolution step 735: f(x)= 3.0653783150506744
# differential_evolution step 736: f(x)= 3.0653783150506744
# differential_evolution step 737: f(x)= 3.0653783150506744
# differential_evolution step 738: f(x)= 3.0653783150506744
# differential_evolution step 739: f(x)= 3.0653783150506744
# differential_evolution step 740: f(x)= 3.0653783150506744
# differential_evolution step 741: f(x)= 3.0653783150506744
# differential_evolution step 742: f(x)= 3.0653783150506744
# differential_evolution step 743: f(x)= 3.0653783150506744
# differential_evolution step 744: f(x)= 3.0653783150506744
# differential_evolution step 745: f(x)= 3.0653783150506744
# differential_evolution step 746: f(x)= 3.0653783150506744
# differential_evolution step 747: f(x)= 3.0653783150506744
# differential_evolution step 748: f(x)= 3.061563239023776
# differential_evolution step 749: f(x)= 3.061563239023776
# differential_evolution step 750: f(x)= 3.061563239023776
# differential_evolution step 751: f(x)= 3.061563239023776
# differential_evolution step 752: f(x)= 3.061563239023776
# differential_evolution step 753: f(x)= 3.061563239023776
# differential_evolution step 754: f(x)= 3.061563239023776
# differential_evolution step 755: f(x)= 3.061563239023776
# differential_evolution step 756: f(x)= 3.061563239023776
# differential_evolution step 757: f(x)= 3.061563239023776
# differential_evolution step 758: f(x)= 3.061563239023776
# differential_evolution step 759: f(x)= 3.061563239023776
# differential_evolution step 760: f(x)= 3.061563239023776
# differential_evolution step 761: f(x)= 3.061563239023776
# differential_evolution step 762: f(x)= 3.061563239023776
# differential_evolution step 763: f(x)= 3.061563239023776
# differential_evolution step 764: f(x)= 3.061563239023776
# differential_evolution step 765: f(x)= 3.061563239023776
# differential_evolution step 766: f(x)= 3.061563239023776
# differential_evolution step 767: f(x)= 3.061563239023776
# differential_evolution step 768: f(x)= 3.061563239023776
# differential_evolution step 769: f(x)= 3.061563239023776
# differential_evolution step 770: f(x)= 3.061563239023776
# differential_evolution step 771: f(x)= 3.061563239023776
# differential_evolution step 772: f(x)= 3.061563239023776
# differential_evolution step 773: f(x)= 3.061563239023776
# differential_evolution step 774: f(x)= 3.061563239023776
# differential_evolution step 775: f(x)= 3.061563239023776
# differential_evolution step 776: f(x)= 3.061563239023776
# differential_evolution step 777: f(x)= 3.061563239023776
# differential_evolution step 778: f(x)= 3.061563239023776
# differential_evolution step 779: f(x)= 3.061563239023776
# differential_evolution step 780: f(x)= 3.0448829981933097
# differential_evolution step 781: f(x)= 3.0448829981933097
# differential_evolution step 782: f(x)= 3.0448829981933097
# differential_evolution step 783: f(x)= 3.0448829981933097
# differential_evolution step 784: f(x)= 3.0448829981933097
# differential_evolution step 785: f(x)= 3.0448829981933097
# differential_evolution step 786: f(x)= 3.044555770382418
# differential_evolution step 787: f(x)= 3.038185081642784
# differential_evolution step 788: f(x)= 3.038185081642784
# differential_evolution step 789: f(x)= 3.038185081642784
# differential_evolution step 790: f(x)= 3.038185081642784
# differential_evolution step 791: f(x)= 3.038185081642784
# differential_evolution step 792: f(x)= 3.038185081642784
# differential_evolution step 793: f(x)= 3.038185081642784
# differential_evolution step 794: f(x)= 3.038185081642784
# differential_evolution step 795: f(x)= 3.038185081642784
# differential_evolution step 796: f(x)= 3.038185081642784
# differential_evolution step 797: f(x)= 3.038185081642784
# differential_evolution step 798: f(x)= 3.038185081642784
# differential_evolution step 799: f(x)= 3.038185081642784
# differential_evolution step 800: f(x)= 3.038185081642784
# differential_evolution step 801: f(x)= 3.038185081642784
# differential_evolution step 802: f(x)= 3.038185081642784
# differential_evolution step 803: f(x)= 3.038185081642784
# differential_evolution step 804: f(x)= 3.038185081642784
# differential_evolution step 805: f(x)= 3.038185081642784
# differential_evolution step 806: f(x)= 3.038185081642784
# differential_evolution step 807: f(x)= 3.038185081642784
# differential_evolution step 808: f(x)= 3.038185081642784
# differential_evolution step 809: f(x)= 3.038185081642784
# differential_evolution step 810: f(x)= 3.038185081642784
# differential_evolution step 811: f(x)= 3.038185081642784
# differential_evolution step 812: f(x)= 3.038185081642784
# differential_evolution step 813: f(x)= 3.038185081642784
# differential_evolution step 814: f(x)= 3.038185081642784
# differential_evolution step 815: f(x)= 3.038185081642784
# differential_evolution step 816: f(x)= 3.038185081642784
# differential_evolution step 817: f(x)= 3.038185081642784
# differential_evolution step 818: f(x)= 3.038185081642784
# differential_evolution step 819: f(x)= 3.038185081642784
# differential_evolution step 820: f(x)= 3.038185081642784
# differential_evolution step 821: f(x)= 3.038185081642784
# differential_evolution step 822: f(x)= 3.038185081642784
# differential_evolution step 823: f(x)= 3.038185081642784
# differential_evolution step 824: f(x)= 3.038185081642784
# differential_evolution step 825: f(x)= 3.038185081642784
# differential_evolution step 826: f(x)= 3.038185081642784
# differential_evolution step 827: f(x)= 3.038185081642784
# differential_evolution step 828: f(x)= 3.038185081642784
# differential_evolution step 829: f(x)= 3.038185081642784
# differential_evolution step 830: f(x)= 3.038185081642784
# differential_evolution step 831: f(x)= 3.038185081642784
# differential_evolution step 832: f(x)= 3.038185081642784
# differential_evolution step 833: f(x)= 3.038185081642784
# differential_evolution step 834: f(x)= 3.038185081642784
# differential_evolution step 835: f(x)= 3.038185081642784
# differential_evolution step 836: f(x)= 3.038185081642784
# differential_evolution step 837: f(x)= 3.038185081642784
# differential_evolution step 838: f(x)= 3.038185081642784
# differential_evolution step 839: f(x)= 3.038185081642784
# differential_evolution step 840: f(x)= 3.038185081642784
# differential_evolution step 841: f(x)= 3.038185081642784
# differential_evolution step 842: f(x)= 3.038185081642784
# differential_evolution step 843: f(x)= 3.038185081642784
# differential_evolution step 844: f(x)= 3.038185081642784
# differential_evolution step 845: f(x)= 3.038185081642784
# differential_evolution step 846: f(x)= 3.038185081642784
# differential_evolution step 847: f(x)= 3.038185081642784
# differential_evolution step 848: f(x)= 3.038185081642784
# differential_evolution step 849: f(x)= 3.038185081642784
# differential_evolution step 850: f(x)= 3.038185081642784
# differential_evolution step 851: f(x)= 3.038185081642784
# differential_evolution step 852: f(x)= 3.038185081642784
# differential_evolution step 853: f(x)= 3.038185081642784
# differential_evolution step 854: f(x)= 3.038185081642784
# differential_evolution step 855: f(x)= 3.038185081642784
# differential_evolution step 856: f(x)= 3.038185081642784
# differential_evolution step 857: f(x)= 3.038185081642784
# differential_evolution step 858: f(x)= 3.038185081642784
# differential_evolution step 859: f(x)= 3.038185081642784
# differential_evolution step 860: f(x)= 3.038185081642784
# differential_evolution step 861: f(x)= 3.038185081642784
# differential_evolution step 862: f(x)= 3.038185081642784
# differential_evolution step 863: f(x)= 3.038185081642784
# differential_evolution step 864: f(x)= 3.038185081642784
# differential_evolution step 865: f(x)= 3.038185081642784
# differential_evolution step 866: f(x)= 3.038185081642784
# differential_evolution step 867: f(x)= 3.038185081642784
# differential_evolution step 868: f(x)= 3.038185081642784
# differential_evolution step 869: f(x)= 3.038185081642784
# differential_evolution step 870: f(x)= 3.038185081642784
# differential_evolution step 871: f(x)= 3.038185081642784
# differential_evolution step 872: f(x)= 3.038185081642784
# differential_evolution step 873: f(x)= 3.038185081642784
# differential_evolution step 874: f(x)= 3.038185081642784
# differential_evolution step 875: f(x)= 3.038185081642784
# differential_evolution step 876: f(x)= 3.038185081642784
# differential_evolution step 877: f(x)= 3.038185081642784
# differential_evolution step 878: f(x)= 3.038185081642784
# differential_evolution step 879: f(x)= 3.038185081642784
# differential_evolution step 880: f(x)= 3.038185081642784
# differential_evolution step 881: f(x)= 3.038185081642784
# differential_evolution step 882: f(x)= 3.038185081642784
# differential_evolution step 883: f(x)= 3.038185081642784
# differential_evolution step 884: f(x)= 3.038185081642784
# differential_evolution step 885: f(x)= 3.038185081642784
# differential_evolution step 886: f(x)= 3.038185081642784
# differential_evolution step 887: f(x)= 3.038185081642784
# differential_evolution step 888: f(x)= 3.038185081642784
# differential_evolution step 889: f(x)= 3.038185081642784
# differential_evolution step 890: f(x)= 3.038185081642784
# differential_evolution step 891: f(x)= 3.038185081642784
# differential_evolution step 892: f(x)= 3.038185081642784
# differential_evolution step 893: f(x)= 3.038185081642784
# differential_evolution step 894: f(x)= 3.038185081642784
# differential_evolution step 895: f(x)= 3.038185081642784
# differential_evolution step 896: f(x)= 3.038185081642784
# differential_evolution step 897: f(x)= 3.038185081642784
# differential_evolution step 898: f(x)= 3.038185081642784
# differential_evolution step 899: f(x)= 3.038185081642784
# differential_evolution step 900: f(x)= 3.038185081642784
# differential_evolution step 901: f(x)= 3.038185081642784
# differential_evolution step 902: f(x)= 3.038185081642784
# differential_evolution step 903: f(x)= 3.038185081642784
# differential_evolution step 904: f(x)= 3.038185081642784
# differential_evolution step 905: f(x)= 3.038185081642784
# differential_evolution step 906: f(x)= 3.038185081642784
# differential_evolution step 907: f(x)= 3.038185081642784
# differential_evolution step 908: f(x)= 3.038185081642784
# differential_evolution step 909: f(x)= 3.038185081642784
# differential_evolution step 910: f(x)= 3.038185081642784
# differential_evolution step 911: f(x)= 3.038185081642784
# differential_evolution step 912: f(x)= 3.038185081642784
# differential_evolution step 913: f(x)= 3.038185081642784
# differential_evolution step 914: f(x)= 3.038185081642784
# differential_evolution step 915: f(x)= 3.038185081642784
# differential_evolution step 916: f(x)= 3.038185081642784
# differential_evolution step 917: f(x)= 3.038185081642784
# differential_evolution step 918: f(x)= 3.0313182180526597
# differential_evolution step 919: f(x)= 3.0313182180526597
# differential_evolution step 920: f(x)= 3.0313182180526597
# differential_evolution step 921: f(x)= 3.0313182180526597
# differential_evolution step 922: f(x)= 3.0313182180526597
# differential_evolution step 923: f(x)= 3.0313182180526597
# differential_evolution step 924: f(x)= 3.0283799600189587
# differential_evolution step 925: f(x)= 3.01752277590828
# differential_evolution step 926: f(x)= 3.01752277590828
# differential_evolution step 927: f(x)= 3.01752277590828
# differential_evolution step 928: f(x)= 3.01752277590828
# differential_evolution step 929: f(x)= 3.01752277590828
# differential_evolution step 930: f(x)= 3.009105995965864
# differential_evolution step 931: f(x)= 3.009105995965864
# differential_evolution step 932: f(x)= 3.009105995965864
# differential_evolution step 933: f(x)= 3.009105995965864
# differential_evolution step 934: f(x)= 3.009105995965864
# differential_evolution step 935: f(x)= 3.009105995965864
# differential_evolution step 936: f(x)= 3.009105995965864
# differential_evolution step 937: f(x)= 3.009105995965864
# differential_evolution step 938: f(x)= 3.009105995965864
# differential_evolution step 939: f(x)= 3.009105995965864
# differential_evolution step 940: f(x)= 3.009105995965864
# differential_evolution step 941: f(x)= 3.009105995965864
# differential_evolution step 942: f(x)= 3.009105995965864
# differential_evolution step 943: f(x)= 3.009105995965864
# differential_evolution step 944: f(x)= 3.009105995965864
# differential_evolution step 945: f(x)= 3.009105995965864
# differential_evolution step 946: f(x)= 3.009105995965864
# differential_evolution step 947: f(x)= 3.009105995965864
# differential_evolution step 948: f(x)= 3.009105995965864
# differential_evolution step 949: f(x)= 3.009105995965864
# differential_evolution step 950: f(x)= 3.009105995965864
# differential_evolution step 951: f(x)= 3.009105995965864
# differential_evolution step 952: f(x)= 3.009105995965864
# differential_evolution step 953: f(x)= 3.009105995965864
# differential_evolution step 954: f(x)= 3.009105995965864
# differential_evolution step 955: f(x)= 3.009105995965864
# differential_evolution step 956: f(x)= 3.009105995965864
# differential_evolution step 957: f(x)= 3.009105995965864
# differential_evolution step 958: f(x)= 3.009105995965864
# differential_evolution step 959: f(x)= 3.009105995965864
# differential_evolution step 960: f(x)= 3.009105995965864
# differential_evolution step 961: f(x)= 3.009105995965864
# differential_evolution step 962: f(x)= 3.009105995965864
# differential_evolution step 963: f(x)= 3.009105995965864
# differential_evolution step 964: f(x)= 3.009105995965864
# differential_evolution step 965: f(x)= 3.009105995965864
# differential_evolution step 966: f(x)= 3.009105995965864
# differential_evolution step 967: f(x)= 3.009105995965864
# differential_evolution step 968: f(x)= 3.009105995965864
# differential_evolution step 969: f(x)= 3.009105995965864
# differential_evolution step 970: f(x)= 3.009105995965864
# differential_evolution step 971: f(x)= 3.009105995965864
# differential_evolution step 972: f(x)= 3.009105995965864
# differential_evolution step 973: f(x)= 3.009105995965864
# differential_evolution step 974: f(x)= 3.009105995965864
# differential_evolution step 975: f(x)= 3.009105995965864
# differential_evolution step 976: f(x)= 3.0081156493281416
# differential_evolution step 977: f(x)= 3.0081156493281416
# differential_evolution step 978: f(x)= 3.005342734678807
# differential_evolution step 979: f(x)= 3.005342734678807
# differential_evolution step 980: f(x)= 3.005342734678807
# differential_evolution step 981: f(x)= 3.005342734678807
# differential_evolution step 982: f(x)= 3.005342734678807
# differential_evolution step 983: f(x)= 3.005342734678807
# differential_evolution step 984: f(x)= 3.005342734678807
# differential_evolution step 985: f(x)= 3.005342734678807
# differential_evolution step 986: f(x)= 3.005342734678807
# differential_evolution step 987: f(x)= 3.005342734678807
# differential_evolution step 988: f(x)= 3.005342734678807
# differential_evolution step 989: f(x)= 3.005342734678807
# differential_evolution step 990: f(x)= 3.002028119546184
# differential_evolution step 991: f(x)= 3.002028119546184
# differential_evolution step 992: f(x)= 2.996884689331079
# differential_evolution step 993: f(x)= 2.996884689331079
# differential_evolution step 994: f(x)= 2.996884689331079
# differential_evolution step 995: f(x)= 2.996884689331079
# differential_evolution step 996: f(x)= 2.996884689331079
# differential_evolution step 997: f(x)= 2.996884689331079
# differential_evolution step 998: f(x)= 2.996884689331079
# differential_evolution step 999: f(x)= 2.996884689331079
# differential_evolution step 1000: f(x)= 2.993388873814999
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [3.98297287e-02 1.70234112e+01 4.24441130e+00 2.87914478e+01
#  9.95920878e-03 4.73480335e+01 3.99122861e+00 5.69790644e+01
#  7.51605842e-02 2.33165823e+01 2.05066665e+00 7.72902812e+01
#  5.23471896e-01 1.51634327e+00 1.00356324e+00 8.30000000e+01]
# Chi quadro minimo: 2.9600525644890516

# %%
# Plots:
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, 
                                         sigma = radial_profile_error_HA, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0384, r_e=17.0248, n=4.2403, x_0=28.7914
# Sérsic 2: I_e=0.0096, r_e=47.3435, n=4.0029, x_0=56.9880
# Sérsic 3: I_e=0.0729, r_e=23.3057, n=2.0613, x_0=77.2883
# Sérsic 4: I_e=0.5249, r_e=1.5165, n=1.0041, x_0=83.0000
# [3.31868423e-01 9.14519337e+01 1.19918975e+01 2.74611617e-04
#  1.35457648e-01 4.80778589e+02 1.33751911e+01 2.00549845e-01
#  1.41362111e-01 3.40414730e+01 1.46764946e+00 5.95239117e-01
#  1.59522257e+00 2.02274678e+00 2.86657595e+00 3.90800078e-01]
# 290.77883649783996
# 329.33305336530987 290.77883649783996 364.46155947364946 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (76, 78),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (81, 83),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 16),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 85293.96564182793
# differential_evolution step 2: f(x)= 43864.01756270464
# differential_evolution step 3: f(x)= 25099.880156799525
# differential_evolution step 4: f(x)= 7175.6942276697655
# differential_evolution step 5: f(x)= 7175.6942276697655
# differential_evolution step 6: f(x)= 7175.6942276697655
# differential_evolution step 7: f(x)= 5936.346879398361
# differential_evolution step 8: f(x)= 5936.346879398361
# differential_evolution step 9: f(x)= 5936.346879398361
# differential_evolution step 10: f(x)= 5398.342096671354
# differential_evolution step 11: f(x)= 1543.5798819358922
# differential_evolution step 12: f(x)= 1543.5798819358922
# differential_evolution step 13: f(x)= 1523.4529743146784
# differential_evolution step 14: f(x)= 1523.4529743146784
# differential_evolution step 15: f(x)= 195.78168326387308
# differential_evolution step 16: f(x)= 195.78168326387308
# differential_evolution step 17: f(x)= 195.78168326387308
# differential_evolution step 18: f(x)= 195.78168326387308
# differential_evolution step 19: f(x)= 195.78168326387308
# differential_evolution step 20: f(x)= 195.78168326387308
# differential_evolution step 21: f(x)= 195.78168326387308
# differential_evolution step 22: f(x)= 195.78168326387308
# differential_evolution step 23: f(x)= 149.3102858829605
# differential_evolution step 24: f(x)= 149.3102858829605
# differential_evolution step 25: f(x)= 149.3102858829605
# differential_evolution step 26: f(x)= 149.3102858829605
# differential_evolution step 27: f(x)= 149.3102858829605
# differential_evolution step 28: f(x)= 49.62349095300998
# differential_evolution step 29: f(x)= 49.62349095300998
# differential_evolution step 30: f(x)= 49.62349095300998
# differential_evolution step 31: f(x)= 49.62349095300998
# differential_evolution step 32: f(x)= 44.29498739818784
# differential_evolution step 33: f(x)= 44.29498739818784
# differential_evolution step 34: f(x)= 44.29498739818784
# differential_evolution step 35: f(x)= 44.29498739818784
# differential_evolution step 36: f(x)= 44.29498739818784
# differential_evolution step 37: f(x)= 34.28783563829403
# differential_evolution step 38: f(x)= 34.28783563829403
# differential_evolution step 39: f(x)= 34.28783563829403
# differential_evolution step 40: f(x)= 34.28783563829403
# differential_evolution step 41: f(x)= 28.3329708500181
# differential_evolution step 42: f(x)= 28.3329708500181
# differential_evolution step 43: f(x)= 28.3329708500181
# differential_evolution step 44: f(x)= 28.3329708500181
# differential_evolution step 45: f(x)= 28.3329708500181
# differential_evolution step 46: f(x)= 28.3329708500181
# differential_evolution step 47: f(x)= 28.3329708500181
# differential_evolution step 48: f(x)= 28.3329708500181
# differential_evolution step 49: f(x)= 28.3329708500181
# differential_evolution step 50: f(x)= 28.3329708500181
# differential_evolution step 51: f(x)= 22.79008029500399
# differential_evolution step 52: f(x)= 15.524764192440822
# differential_evolution step 53: f(x)= 15.524764192440822
# differential_evolution step 54: f(x)= 15.524764192440822
# differential_evolution step 55: f(x)= 15.524764192440822
# differential_evolution step 56: f(x)= 13.425199483507479
# differential_evolution step 57: f(x)= 13.425199483507479
# differential_evolution step 58: f(x)= 13.425199483507479
# differential_evolution step 59: f(x)= 13.425199483507479
# differential_evolution step 60: f(x)= 13.425199483507479
# differential_evolution step 61: f(x)= 12.131038599583242
# differential_evolution step 62: f(x)= 12.131038599583242
# differential_evolution step 63: f(x)= 12.131038599583242
# differential_evolution step 64: f(x)= 12.131038599583242
# differential_evolution step 65: f(x)= 12.092838904444612
# differential_evolution step 66: f(x)= 12.092838904444612
# differential_evolution step 67: f(x)= 12.092838904444612
# differential_evolution step 68: f(x)= 12.092838904444612
# differential_evolution step 69: f(x)= 12.092838904444612
# differential_evolution step 70: f(x)= 12.092838904444612
# differential_evolution step 71: f(x)= 12.092838904444612
# differential_evolution step 72: f(x)= 10.84583566596045
# differential_evolution step 73: f(x)= 7.399677963957067
# differential_evolution step 74: f(x)= 7.399677963957067
# differential_evolution step 75: f(x)= 7.399677963957067
# differential_evolution step 76: f(x)= 7.399677963957067
# differential_evolution step 77: f(x)= 7.399677963957067
# differential_evolution step 78: f(x)= 7.399677963957067
# differential_evolution step 79: f(x)= 6.228148927154074
# differential_evolution step 80: f(x)= 6.228148927154074
# differential_evolution step 81: f(x)= 6.228148927154074
# differential_evolution step 82: f(x)= 6.228148927154074
# differential_evolution step 83: f(x)= 6.228148927154074
# differential_evolution step 84: f(x)= 6.228148927154074
# differential_evolution step 85: f(x)= 6.228148927154074
# differential_evolution step 86: f(x)= 6.228148927154074
# differential_evolution step 87: f(x)= 6.228148927154074
# differential_evolution step 88: f(x)= 6.228148927154074
# differential_evolution step 89: f(x)= 6.228148927154074
# differential_evolution step 90: f(x)= 6.228148927154074
# differential_evolution step 91: f(x)= 6.228148927154074
# differential_evolution step 92: f(x)= 6.228148927154074
# differential_evolution step 93: f(x)= 6.228148927154074
# differential_evolution step 94: f(x)= 5.401611218947435
# differential_evolution step 95: f(x)= 5.05392985826505
# differential_evolution step 96: f(x)= 5.05392985826505
# differential_evolution step 97: f(x)= 5.05392985826505
# differential_evolution step 98: f(x)= 5.05392985826505
# differential_evolution step 99: f(x)= 4.498017262016916
# differential_evolution step 100: f(x)= 4.498017262016916
# differential_evolution step 101: f(x)= 4.498017262016916
# differential_evolution step 102: f(x)= 4.498017262016916
# differential_evolution step 103: f(x)= 4.498017262016916
# differential_evolution step 104: f(x)= 4.498017262016916
# differential_evolution step 105: f(x)= 4.498017262016916
# differential_evolution step 106: f(x)= 4.498017262016916
# differential_evolution step 107: f(x)= 4.498017262016916
# differential_evolution step 108: f(x)= 4.498017262016916
# differential_evolution step 109: f(x)= 4.498017262016916
# differential_evolution step 110: f(x)= 4.498017262016916
# differential_evolution step 111: f(x)= 4.498017262016916
# differential_evolution step 112: f(x)= 4.498017262016916
# differential_evolution step 113: f(x)= 4.498017262016916
# differential_evolution step 114: f(x)= 4.498017262016916
# differential_evolution step 115: f(x)= 4.498017262016916
# differential_evolution step 116: f(x)= 4.498017262016916
# differential_evolution step 117: f(x)= 4.498017262016916
# differential_evolution step 118: f(x)= 4.498017262016916
# differential_evolution step 119: f(x)= 4.498017262016916
# differential_evolution step 120: f(x)= 4.498017262016916
# differential_evolution step 121: f(x)= 4.498017262016916
# differential_evolution step 122: f(x)= 4.498017262016916
# differential_evolution step 123: f(x)= 3.958538070788886
# differential_evolution step 124: f(x)= 3.958538070788886
# differential_evolution step 125: f(x)= 3.958538070788886
# differential_evolution step 126: f(x)= 3.958538070788886
# differential_evolution step 127: f(x)= 3.958538070788886
# differential_evolution step 128: f(x)= 3.958538070788886
# differential_evolution step 129: f(x)= 3.958538070788886
# differential_evolution step 130: f(x)= 3.958538070788886
# differential_evolution step 131: f(x)= 3.7826116344653076
# differential_evolution step 132: f(x)= 3.7826116344653076
# differential_evolution step 133: f(x)= 3.1573449485809064
# differential_evolution step 134: f(x)= 3.1573449485809064
# differential_evolution step 135: f(x)= 3.1573449485809064
# differential_evolution step 136: f(x)= 3.1573449485809064
# differential_evolution step 137: f(x)= 3.1573449485809064
# differential_evolution step 138: f(x)= 3.1573449485809064
# differential_evolution step 139: f(x)= 3.1573449485809064
# differential_evolution step 140: f(x)= 3.1573449485809064
# differential_evolution step 141: f(x)= 3.1573449485809064
# differential_evolution step 142: f(x)= 3.1573449485809064
# differential_evolution step 143: f(x)= 3.1573449485809064
# differential_evolution step 144: f(x)= 3.1573449485809064
# differential_evolution step 145: f(x)= 3.1573449485809064
# differential_evolution step 146: f(x)= 3.1573449485809064
# differential_evolution step 147: f(x)= 3.1573449485809064
# differential_evolution step 148: f(x)= 2.789010332448581
# differential_evolution step 149: f(x)= 2.789010332448581
# differential_evolution step 150: f(x)= 2.789010332448581
# differential_evolution step 151: f(x)= 2.789010332448581
# differential_evolution step 152: f(x)= 2.789010332448581
# differential_evolution step 153: f(x)= 2.789010332448581
# differential_evolution step 154: f(x)= 2.789010332448581
# differential_evolution step 155: f(x)= 2.789010332448581
# differential_evolution step 156: f(x)= 2.789010332448581
# differential_evolution step 157: f(x)= 2.004547692622108
# differential_evolution step 158: f(x)= 2.004547692622108
# differential_evolution step 159: f(x)= 2.004547692622108
# differential_evolution step 160: f(x)= 2.004547692622108
# differential_evolution step 161: f(x)= 2.004547692622108
# differential_evolution step 162: f(x)= 2.004547692622108
# differential_evolution step 163: f(x)= 2.004547692622108
# differential_evolution step 164: f(x)= 2.004547692622108
# differential_evolution step 165: f(x)= 2.004547692622108
# differential_evolution step 166: f(x)= 2.004547692622108
# differential_evolution step 167: f(x)= 2.004547692622108
# differential_evolution step 168: f(x)= 2.004547692622108
# differential_evolution step 169: f(x)= 2.004547692622108
# differential_evolution step 170: f(x)= 2.004547692622108
# differential_evolution step 171: f(x)= 2.004547692622108
# differential_evolution step 172: f(x)= 2.004547692622108
# differential_evolution step 173: f(x)= 2.004547692622108
# differential_evolution step 174: f(x)= 2.004547692622108
# differential_evolution step 175: f(x)= 2.004547692622108
# differential_evolution step 176: f(x)= 2.004547692622108
# differential_evolution step 177: f(x)= 2.004547692622108
# differential_evolution step 178: f(x)= 2.004547692622108
# differential_evolution step 179: f(x)= 2.004547692622108
# differential_evolution step 180: f(x)= 2.004547692622108
# differential_evolution step 181: f(x)= 2.004547692622108
# differential_evolution step 182: f(x)= 2.004547692622108
# differential_evolution step 183: f(x)= 2.004547692622108
# differential_evolution step 184: f(x)= 2.004547692622108
# differential_evolution step 185: f(x)= 2.004547692622108
# differential_evolution step 186: f(x)= 2.004547692622108
# differential_evolution step 187: f(x)= 2.004547692622108
# differential_evolution step 188: f(x)= 2.004547692622108
# differential_evolution step 189: f(x)= 2.004547692622108
# differential_evolution step 190: f(x)= 2.004547692622108
# differential_evolution step 191: f(x)= 2.004547692622108
# differential_evolution step 192: f(x)= 2.004547692622108
# differential_evolution step 193: f(x)= 2.004547692622108
# differential_evolution step 194: f(x)= 2.004547692622108
# differential_evolution step 195: f(x)= 2.004547692622108
# differential_evolution step 196: f(x)= 2.004547692622108
# differential_evolution step 197: f(x)= 1.9854143406334264
# differential_evolution step 198: f(x)= 1.9854143406334264
# differential_evolution step 199: f(x)= 1.9854143406334264
# differential_evolution step 200: f(x)= 1.631421394071142
# differential_evolution step 201: f(x)= 1.631421394071142
# differential_evolution step 202: f(x)= 1.631421394071142
# differential_evolution step 203: f(x)= 1.631421394071142
# differential_evolution step 204: f(x)= 1.631421394071142
# differential_evolution step 205: f(x)= 1.631421394071142
# differential_evolution step 206: f(x)= 1.631421394071142
# differential_evolution step 207: f(x)= 1.631421394071142
# differential_evolution step 208: f(x)= 1.631421394071142
# differential_evolution step 209: f(x)= 1.631421394071142
# differential_evolution step 210: f(x)= 1.631421394071142
# differential_evolution step 211: f(x)= 1.5950842429888406
# differential_evolution step 212: f(x)= 1.5950842429888406
# differential_evolution step 213: f(x)= 1.5950842429888406
# differential_evolution step 214: f(x)= 1.3349420912880856
# differential_evolution step 215: f(x)= 1.3349420912880856
# differential_evolution step 216: f(x)= 1.3349420912880856
# differential_evolution step 217: f(x)= 1.3349420912880856
# differential_evolution step 218: f(x)= 1.3349420912880856
# differential_evolution step 219: f(x)= 1.3349420912880856
# differential_evolution step 220: f(x)= 1.3349420912880856
# differential_evolution step 221: f(x)= 1.3349420912880856
# differential_evolution step 222: f(x)= 1.3349420912880856
# differential_evolution step 223: f(x)= 1.3349420912880856
# differential_evolution step 224: f(x)= 1.2095871475116629
# differential_evolution step 225: f(x)= 1.2095871475116629
# differential_evolution step 226: f(x)= 1.2095871475116629
# differential_evolution step 227: f(x)= 1.2095871475116629
# differential_evolution step 228: f(x)= 1.2095871475116629
# differential_evolution step 229: f(x)= 1.2095871475116629
# differential_evolution step 230: f(x)= 1.2095871475116629
# differential_evolution step 231: f(x)= 1.2095871475116629
# differential_evolution step 232: f(x)= 1.2095871475116629
# differential_evolution step 233: f(x)= 1.2095871475116629
# differential_evolution step 234: f(x)= 1.2095871475116629
# differential_evolution step 235: f(x)= 1.2095871475116629
# differential_evolution step 236: f(x)= 1.2095871475116629
# differential_evolution step 237: f(x)= 1.2095871475116629
# differential_evolution step 238: f(x)= 1.2095871475116629
# differential_evolution step 239: f(x)= 1.2095871475116629
# differential_evolution step 240: f(x)= 1.2095871475116629
# differential_evolution step 241: f(x)= 1.2095871475116629
# differential_evolution step 242: f(x)= 1.2095871475116629
# differential_evolution step 243: f(x)= 1.2095871475116629
# differential_evolution step 244: f(x)= 1.2095871475116629
# differential_evolution step 245: f(x)= 1.2095871475116629
# differential_evolution step 246: f(x)= 1.2095871475116629
# differential_evolution step 247: f(x)= 1.2095871475116629
# differential_evolution step 248: f(x)= 1.2095871475116629
# differential_evolution step 249: f(x)= 1.2095871475116629
# differential_evolution step 250: f(x)= 1.2095871475116629
# differential_evolution step 251: f(x)= 1.2095871475116629
# differential_evolution step 252: f(x)= 1.2095871475116629
# differential_evolution step 253: f(x)= 1.2095871475116629
# differential_evolution step 254: f(x)= 1.108066557083573
# differential_evolution step 255: f(x)= 1.108066557083573
# differential_evolution step 256: f(x)= 1.108066557083573
# differential_evolution step 257: f(x)= 1.108066557083573
# differential_evolution step 258: f(x)= 1.108066557083573
# differential_evolution step 259: f(x)= 1.0743232936413394
# differential_evolution step 260: f(x)= 1.0743232936413394
# differential_evolution step 261: f(x)= 1.0743232936413394
# differential_evolution step 262: f(x)= 1.0743232936413394
# differential_evolution step 263: f(x)= 1.0743232936413394
# differential_evolution step 264: f(x)= 1.0743232936413394
# differential_evolution step 265: f(x)= 1.0743232936413394
# differential_evolution step 266: f(x)= 1.0743232936413394
# differential_evolution step 267: f(x)= 1.0743232936413394
# differential_evolution step 268: f(x)= 1.0743232936413394
# differential_evolution step 269: f(x)= 1.0743232936413394
# differential_evolution step 270: f(x)= 1.0743232936413394
# differential_evolution step 271: f(x)= 1.0743232936413394
# differential_evolution step 272: f(x)= 1.0743232936413394
# differential_evolution step 273: f(x)= 0.9033977069980373
# differential_evolution step 274: f(x)= 0.9033977069980373
# differential_evolution step 275: f(x)= 0.9033977069980373
# differential_evolution step 276: f(x)= 0.9033977069980373
# differential_evolution step 277: f(x)= 0.9033977069980373
# differential_evolution step 278: f(x)= 0.9033977069980373
# differential_evolution step 279: f(x)= 0.9033977069980373
# differential_evolution step 280: f(x)= 0.9033977069980373
# differential_evolution step 281: f(x)= 0.9033977069980373
# differential_evolution step 282: f(x)= 0.9033977069980373
# differential_evolution step 283: f(x)= 0.9033977069980373
# differential_evolution step 284: f(x)= 0.9033977069980373
# differential_evolution step 285: f(x)= 0.9033977069980373
# differential_evolution step 286: f(x)= 0.8352710586756549
# differential_evolution step 287: f(x)= 0.8306229041802085
# differential_evolution step 288: f(x)= 0.8306229041802085
# differential_evolution step 289: f(x)= 0.8306229041802085
# differential_evolution step 290: f(x)= 0.8306229041802085
# differential_evolution step 291: f(x)= 0.8306229041802085
# differential_evolution step 292: f(x)= 0.8306229041802085
# differential_evolution step 293: f(x)= 0.8306229041802085
# differential_evolution step 294: f(x)= 0.8306229041802085
# differential_evolution step 295: f(x)= 0.8306229041802085
# differential_evolution step 296: f(x)= 0.8306229041802085
# differential_evolution step 297: f(x)= 0.8306229041802085
# differential_evolution step 298: f(x)= 0.7283607397123635
# differential_evolution step 299: f(x)= 0.7283607397123635
# differential_evolution step 300: f(x)= 0.7283607397123635
# differential_evolution step 301: f(x)= 0.7037011418059305
# differential_evolution step 302: f(x)= 0.7037011418059305
# differential_evolution step 303: f(x)= 0.7037011418059305
# differential_evolution step 304: f(x)= 0.7037011418059305
# differential_evolution step 305: f(x)= 0.7037011418059305
# differential_evolution step 306: f(x)= 0.7037011418059305
# differential_evolution step 307: f(x)= 0.7037011418059305
# differential_evolution step 308: f(x)= 0.7037011418059305
# differential_evolution step 309: f(x)= 0.7037011418059305
# differential_evolution step 310: f(x)= 0.7037011418059305
# differential_evolution step 311: f(x)= 0.7037011418059305
# differential_evolution step 312: f(x)= 0.7037011418059305
# differential_evolution step 313: f(x)= 0.7037011418059305
# differential_evolution step 314: f(x)= 0.7037011418059305
# differential_evolution step 315: f(x)= 0.7037011418059305
# differential_evolution step 316: f(x)= 0.7037011418059305
# differential_evolution step 317: f(x)= 0.7037011418059305
# differential_evolution step 318: f(x)= 0.7037011418059305
# differential_evolution step 319: f(x)= 0.7037011418059305
# differential_evolution step 320: f(x)= 0.7037011418059305
# differential_evolution step 321: f(x)= 0.7037011418059305
# differential_evolution step 322: f(x)= 0.7037011418059305
# differential_evolution step 323: f(x)= 0.7037011418059305
# differential_evolution step 324: f(x)= 0.7037011418059305
# differential_evolution step 325: f(x)= 0.7037011418059305
# differential_evolution step 326: f(x)= 0.7037011418059305
# differential_evolution step 327: f(x)= 0.7037011418059305
# differential_evolution step 328: f(x)= 0.7037011418059305
# differential_evolution step 329: f(x)= 0.7037011418059305
# differential_evolution step 330: f(x)= 0.7037011418059305
# differential_evolution step 331: f(x)= 0.7037011418059305
# differential_evolution step 332: f(x)= 0.6982686576196103
# differential_evolution step 333: f(x)= 0.6982686576196103
# differential_evolution step 334: f(x)= 0.6982686576196103
# differential_evolution step 335: f(x)= 0.6982686576196103
# differential_evolution step 336: f(x)= 0.6982686576196103
# differential_evolution step 337: f(x)= 0.6982686576196103
# differential_evolution step 338: f(x)= 0.6982686576196103
# differential_evolution step 339: f(x)= 0.6982686576196103
# differential_evolution step 340: f(x)= 0.6982686576196103
# differential_evolution step 341: f(x)= 0.6982686576196103
# differential_evolution step 342: f(x)= 0.6982686576196103
# differential_evolution step 343: f(x)= 0.6982686576196103
# differential_evolution step 344: f(x)= 0.6879802936214776
# differential_evolution step 345: f(x)= 0.6879802936214776
# differential_evolution step 346: f(x)= 0.6879802936214776
# differential_evolution step 347: f(x)= 0.6879802936214776
# differential_evolution step 348: f(x)= 0.6879802936214776
# differential_evolution step 349: f(x)= 0.6879802936214776
# differential_evolution step 350: f(x)= 0.6879802936214776
# differential_evolution step 351: f(x)= 0.6879802936214776
# differential_evolution step 352: f(x)= 0.6879802936214776
# differential_evolution step 353: f(x)= 0.6879802936214776
# differential_evolution step 354: f(x)= 0.6879802936214776
# differential_evolution step 355: f(x)= 0.6657782669143953
# differential_evolution step 356: f(x)= 0.6657782669143953
# differential_evolution step 357: f(x)= 0.6657782669143953
# differential_evolution step 358: f(x)= 0.6657782669143953
# differential_evolution step 359: f(x)= 0.6657782669143953
# differential_evolution step 360: f(x)= 0.6657782669143953
# differential_evolution step 361: f(x)= 0.6657782669143953
# differential_evolution step 362: f(x)= 0.6542824856584742
# differential_evolution step 363: f(x)= 0.6542824856584742
# differential_evolution step 364: f(x)= 0.6542824856584742
# differential_evolution step 365: f(x)= 0.6473914713111015
# differential_evolution step 366: f(x)= 0.6473914713111015
# differential_evolution step 367: f(x)= 0.5928765270201887
# differential_evolution step 368: f(x)= 0.5928765270201887
# differential_evolution step 369: f(x)= 0.5928765270201887
# differential_evolution step 370: f(x)= 0.5928765270201887
# differential_evolution step 371: f(x)= 0.5928765270201887
# differential_evolution step 372: f(x)= 0.5928765270201887
# differential_evolution step 373: f(x)= 0.5928765270201887
# differential_evolution step 374: f(x)= 0.5928765270201887
# differential_evolution step 375: f(x)= 0.5928765270201887
# differential_evolution step 376: f(x)= 0.5928765270201887
# differential_evolution step 377: f(x)= 0.5928765270201887
# differential_evolution step 378: f(x)= 0.5928765270201887
# differential_evolution step 379: f(x)= 0.5919107387068546
# differential_evolution step 380: f(x)= 0.5919107387068546
# differential_evolution step 381: f(x)= 0.5919107387068546
# differential_evolution step 382: f(x)= 0.5857859354684863
# differential_evolution step 383: f(x)= 0.5857859354684863
# differential_evolution step 384: f(x)= 0.5857859354684863
# differential_evolution step 385: f(x)= 0.5857859354684863
# differential_evolution step 386: f(x)= 0.5857859354684863
# differential_evolution step 387: f(x)= 0.5857859354684863
# differential_evolution step 388: f(x)= 0.5857859354684863
# differential_evolution step 389: f(x)= 0.5857859354684863
# differential_evolution step 390: f(x)= 0.5857859354684863
# differential_evolution step 391: f(x)= 0.5857859354684863
# differential_evolution step 392: f(x)= 0.5857859354684863
# differential_evolution step 393: f(x)= 0.5857859354684863
# differential_evolution step 394: f(x)= 0.5857859354684863
# differential_evolution step 395: f(x)= 0.5857859354684863
# differential_evolution step 396: f(x)= 0.5504793181438788
# differential_evolution step 397: f(x)= 0.5504793181438788
# differential_evolution step 398: f(x)= 0.5504793181438788
# differential_evolution step 399: f(x)= 0.5482135177958112
# differential_evolution step 400: f(x)= 0.5482135177958112
# differential_evolution step 401: f(x)= 0.5482135177958112
# differential_evolution step 402: f(x)= 0.5482135177958112
# differential_evolution step 403: f(x)= 0.5232096587442294
# differential_evolution step 404: f(x)= 0.5232096587442294
# differential_evolution step 405: f(x)= 0.5232096587442294
# differential_evolution step 406: f(x)= 0.5232096587442294
# differential_evolution step 407: f(x)= 0.5232096587442294
# differential_evolution step 408: f(x)= 0.5232096587442294
# differential_evolution step 409: f(x)= 0.5232096587442294
# differential_evolution step 410: f(x)= 0.5232096587442294
# differential_evolution step 411: f(x)= 0.5232096587442294
# differential_evolution step 412: f(x)= 0.5232096587442294
# differential_evolution step 413: f(x)= 0.5232096587442294
# differential_evolution step 414: f(x)= 0.5232096587442294
# differential_evolution step 415: f(x)= 0.5232096587442294
# differential_evolution step 416: f(x)= 0.5232096587442294
# differential_evolution step 417: f(x)= 0.5232096587442294
# differential_evolution step 418: f(x)= 0.5232096587442294
# differential_evolution step 419: f(x)= 0.5232096587442294
# differential_evolution step 420: f(x)= 0.5232096587442294
# differential_evolution step 421: f(x)= 0.5232096587442294
# differential_evolution step 422: f(x)= 0.5232096587442294
# differential_evolution step 423: f(x)= 0.5232096587442294
# differential_evolution step 424: f(x)= 0.5232096587442294
# differential_evolution step 425: f(x)= 0.5232096587442294
# differential_evolution step 426: f(x)= 0.5232096587442294
# differential_evolution step 427: f(x)= 0.5232096587442294
# differential_evolution step 428: f(x)= 0.5232096587442294
# differential_evolution step 429: f(x)= 0.5232096587442294
# differential_evolution step 430: f(x)= 0.5232096587442294
# differential_evolution step 431: f(x)= 0.5232096587442294
# differential_evolution step 432: f(x)= 0.5232096587442294
# differential_evolution step 433: f(x)= 0.5232096587442294
# differential_evolution step 434: f(x)= 0.5232096587442294
# differential_evolution step 435: f(x)= 0.5232096587442294
# differential_evolution step 436: f(x)= 0.51921060365053
# differential_evolution step 437: f(x)= 0.51921060365053
# differential_evolution step 438: f(x)= 0.51921060365053
# differential_evolution step 439: f(x)= 0.51921060365053
# differential_evolution step 440: f(x)= 0.5175971314751009
# differential_evolution step 441: f(x)= 0.49676599636296526
# differential_evolution step 442: f(x)= 0.49676599636296526
# differential_evolution step 443: f(x)= 0.49676599636296526
# differential_evolution step 444: f(x)= 0.49676599636296526
# differential_evolution step 445: f(x)= 0.49676599636296526
# differential_evolution step 446: f(x)= 0.49676599636296526
# differential_evolution step 447: f(x)= 0.49676599636296526
# differential_evolution step 448: f(x)= 0.49676599636296526
# differential_evolution step 449: f(x)= 0.49676599636296526
# differential_evolution step 450: f(x)= 0.49676599636296526
# differential_evolution step 451: f(x)= 0.49676599636296526
# differential_evolution step 452: f(x)= 0.49676599636296526
# differential_evolution step 453: f(x)= 0.49676599636296526
# differential_evolution step 454: f(x)= 0.49676599636296526
# differential_evolution step 455: f(x)= 0.49676599636296526
# differential_evolution step 456: f(x)= 0.49676599636296526
# differential_evolution step 457: f(x)= 0.49676599636296526
# differential_evolution step 458: f(x)= 0.49676599636296526
# differential_evolution step 459: f(x)= 0.4887834187363932
# differential_evolution step 460: f(x)= 0.4887834187363932
# differential_evolution step 461: f(x)= 0.4820821369672776
# differential_evolution step 462: f(x)= 0.4820821369672776
# differential_evolution step 463: f(x)= 0.4820821369672776
# differential_evolution step 464: f(x)= 0.4820821369672776
# differential_evolution step 465: f(x)= 0.4820821369672776
# differential_evolution step 466: f(x)= 0.4820821369672776
# differential_evolution step 467: f(x)= 0.4820821369672776
# differential_evolution step 468: f(x)= 0.4820821369672776
# differential_evolution step 469: f(x)= 0.4820821369672776
# differential_evolution step 470: f(x)= 0.4820821369672776
# differential_evolution step 471: f(x)= 0.47016812339177716
# differential_evolution step 472: f(x)= 0.47016812339177716
# differential_evolution step 473: f(x)= 0.47016812339177716
# differential_evolution step 474: f(x)= 0.4639606514221009
# differential_evolution step 475: f(x)= 0.4639606514221009
# differential_evolution step 476: f(x)= 0.4639606514221009
# differential_evolution step 477: f(x)= 0.4639606514221009
# differential_evolution step 478: f(x)= 0.4639606514221009
# differential_evolution step 479: f(x)= 0.4639606514221009
# differential_evolution step 480: f(x)= 0.4639606514221009
# differential_evolution step 481: f(x)= 0.4639606514221009
# differential_evolution step 482: f(x)= 0.4639606514221009
# differential_evolution step 483: f(x)= 0.4639606514221009
# differential_evolution step 484: f(x)= 0.4639606514221009
# differential_evolution step 485: f(x)= 0.4639606514221009
# differential_evolution step 486: f(x)= 0.4639606514221009
# differential_evolution step 487: f(x)= 0.4639606514221009
# differential_evolution step 488: f(x)= 0.4639606514221009
# differential_evolution step 489: f(x)= 0.4639606514221009
# differential_evolution step 490: f(x)= 0.4639606514221009
# differential_evolution step 491: f(x)= 0.4639606514221009
# differential_evolution step 492: f(x)= 0.4639606514221009
# differential_evolution step 493: f(x)= 0.4639606514221009
# differential_evolution step 494: f(x)= 0.4639606514221009
# differential_evolution step 495: f(x)= 0.4614450954536795
# differential_evolution step 496: f(x)= 0.4614450954536795
# differential_evolution step 497: f(x)= 0.4614450954536795
# differential_evolution step 498: f(x)= 0.4614450954536795
# differential_evolution step 499: f(x)= 0.4614450954536795
# differential_evolution step 500: f(x)= 0.4614450954536795
# differential_evolution step 501: f(x)= 0.4614450954536795
# differential_evolution step 502: f(x)= 0.4614450954536795
# differential_evolution step 503: f(x)= 0.4614450954536795
# differential_evolution step 504: f(x)= 0.4614450954536795
# differential_evolution step 505: f(x)= 0.4614450954536795
# differential_evolution step 506: f(x)= 0.4614450954536795
# differential_evolution step 507: f(x)= 0.4614450954536795
# differential_evolution step 508: f(x)= 0.4563221340752346
# differential_evolution step 509: f(x)= 0.4563221340752346
# differential_evolution step 510: f(x)= 0.4563221340752346
# differential_evolution step 511: f(x)= 0.4563221340752346
# differential_evolution step 512: f(x)= 0.4563221340752346
# differential_evolution step 513: f(x)= 0.4563221340752346
# differential_evolution step 514: f(x)= 0.4563221340752346
# differential_evolution step 515: f(x)= 0.4563221340752346
# differential_evolution step 516: f(x)= 0.4563221340752346
# differential_evolution step 517: f(x)= 0.4563221340752346
# differential_evolution step 518: f(x)= 0.448028805369414
# differential_evolution step 519: f(x)= 0.448028805369414
# differential_evolution step 520: f(x)= 0.448028805369414
# differential_evolution step 521: f(x)= 0.448028805369414
# differential_evolution step 522: f(x)= 0.448028805369414
# differential_evolution step 523: f(x)= 0.448028805369414
# differential_evolution step 524: f(x)= 0.448028805369414
# differential_evolution step 525: f(x)= 0.448028805369414
# differential_evolution step 526: f(x)= 0.448028805369414
# differential_evolution step 527: f(x)= 0.448028805369414
# differential_evolution step 528: f(x)= 0.448028805369414
# differential_evolution step 529: f(x)= 0.448028805369414
# differential_evolution step 530: f(x)= 0.448028805369414
# differential_evolution step 531: f(x)= 0.448028805369414
# differential_evolution step 532: f(x)= 0.44639204099653446
# differential_evolution step 533: f(x)= 0.44639204099653446
# differential_evolution step 534: f(x)= 0.44639204099653446
# differential_evolution step 535: f(x)= 0.44639204099653446
# differential_evolution step 536: f(x)= 0.43838688095593037
# differential_evolution step 537: f(x)= 0.43838688095593037
# differential_evolution step 538: f(x)= 0.43838688095593037
# differential_evolution step 539: f(x)= 0.43838688095593037
# differential_evolution step 540: f(x)= 0.43838688095593037
# differential_evolution step 541: f(x)= 0.43838688095593037
# differential_evolution step 542: f(x)= 0.43838688095593037
# differential_evolution step 543: f(x)= 0.43838688095593037
# differential_evolution step 544: f(x)= 0.4367132624181902
# differential_evolution step 545: f(x)= 0.4367132624181902
# differential_evolution step 546: f(x)= 0.4367132624181902
# differential_evolution step 547: f(x)= 0.4367132624181902
# differential_evolution step 548: f(x)= 0.4367132624181902
# differential_evolution step 549: f(x)= 0.4367132624181902
# differential_evolution step 550: f(x)= 0.4367132624181902
# differential_evolution step 551: f(x)= 0.4367132624181902
# differential_evolution step 552: f(x)= 0.4367132624181902
# differential_evolution step 553: f(x)= 0.4367132624181902
# differential_evolution step 554: f(x)= 0.4367132624181902
# differential_evolution step 555: f(x)= 0.4367132624181902
# differential_evolution step 556: f(x)= 0.4367132624181902
# differential_evolution step 557: f(x)= 0.4367132624181902
# differential_evolution step 558: f(x)= 0.4367132624181902
# differential_evolution step 559: f(x)= 0.4367132624181902
# differential_evolution step 560: f(x)= 0.4367132624181902
# differential_evolution step 561: f(x)= 0.4367132624181902
# differential_evolution step 562: f(x)= 0.4367132624181902
# differential_evolution step 563: f(x)= 0.4367132624181902
# differential_evolution step 564: f(x)= 0.4367132624181902
# differential_evolution step 565: f(x)= 0.4367132624181902
# differential_evolution step 566: f(x)= 0.4367132624181902
# differential_evolution step 567: f(x)= 0.4367132624181902
# differential_evolution step 568: f(x)= 0.4367132624181902
# differential_evolution step 569: f(x)= 0.4367132624181902
# differential_evolution step 570: f(x)= 0.4367132624181902
# differential_evolution step 571: f(x)= 0.4367132624181902
# differential_evolution step 572: f(x)= 0.4367132624181902
# differential_evolution step 573: f(x)= 0.4367132624181902
# differential_evolution step 574: f(x)= 0.4367132624181902
# differential_evolution step 575: f(x)= 0.4367132624181902
# differential_evolution step 576: f(x)= 0.4125820524511627
# differential_evolution step 577: f(x)= 0.41003065047122256
# differential_evolution step 578: f(x)= 0.41003065047122256
# differential_evolution step 579: f(x)= 0.41003065047122256
# differential_evolution step 580: f(x)= 0.41003065047122256
# differential_evolution step 581: f(x)= 0.41003065047122256
# differential_evolution step 582: f(x)= 0.41003065047122256
# differential_evolution step 583: f(x)= 0.41003065047122256
# differential_evolution step 584: f(x)= 0.41003065047122256
# differential_evolution step 585: f(x)= 0.41003065047122256
# differential_evolution step 586: f(x)= 0.41003065047122256
# differential_evolution step 587: f(x)= 0.41003065047122256
# differential_evolution step 588: f(x)= 0.41003065047122256
# differential_evolution step 589: f(x)= 0.41003065047122256
# differential_evolution step 590: f(x)= 0.41003065047122256
# differential_evolution step 591: f(x)= 0.41003065047122256
# differential_evolution step 592: f(x)= 0.41003065047122256
# differential_evolution step 593: f(x)= 0.41003065047122256
# differential_evolution step 594: f(x)= 0.41003065047122256
# differential_evolution step 595: f(x)= 0.41003065047122256
# differential_evolution step 596: f(x)= 0.41003065047122256
# differential_evolution step 597: f(x)= 0.41003065047122256
# differential_evolution step 598: f(x)= 0.41003065047122256
# differential_evolution step 599: f(x)= 0.41003065047122256
# differential_evolution step 600: f(x)= 0.41003065047122256
# differential_evolution step 601: f(x)= 0.41003065047122256
# differential_evolution step 602: f(x)= 0.41003065047122256
# differential_evolution step 603: f(x)= 0.41003065047122256
# differential_evolution step 604: f(x)= 0.41003065047122256
# differential_evolution step 605: f(x)= 0.41003065047122256
# differential_evolution step 606: f(x)= 0.41003065047122256
# differential_evolution step 607: f(x)= 0.41003065047122256
# differential_evolution step 608: f(x)= 0.41003065047122256
# differential_evolution step 609: f(x)= 0.41003065047122256
# differential_evolution step 610: f(x)= 0.41003065047122256
# differential_evolution step 611: f(x)= 0.41003065047122256
# differential_evolution step 612: f(x)= 0.41003065047122256
# differential_evolution step 613: f(x)= 0.41003065047122256
# differential_evolution step 614: f(x)= 0.41003065047122256
# differential_evolution step 615: f(x)= 0.41003065047122256
# differential_evolution step 616: f(x)= 0.41003065047122256
# differential_evolution step 617: f(x)= 0.41003065047122256
# differential_evolution step 618: f(x)= 0.41003065047122256
# differential_evolution step 619: f(x)= 0.41003065047122256
# differential_evolution step 620: f(x)= 0.41003065047122256
# differential_evolution step 621: f(x)= 0.41003065047122256
# differential_evolution step 622: f(x)= 0.41003065047122256
# differential_evolution step 623: f(x)= 0.41003065047122256
# differential_evolution step 624: f(x)= 0.41003065047122256
# differential_evolution step 625: f(x)= 0.41003065047122256
# differential_evolution step 626: f(x)= 0.41003065047122256
# differential_evolution step 627: f(x)= 0.41003065047122256
# differential_evolution step 628: f(x)= 0.41003065047122256
# differential_evolution step 629: f(x)= 0.41003065047122256
# differential_evolution step 630: f(x)= 0.41003065047122256
# differential_evolution step 631: f(x)= 0.41003065047122256
# differential_evolution step 632: f(x)= 0.41003065047122256
# differential_evolution step 633: f(x)= 0.41003065047122256
# differential_evolution step 634: f(x)= 0.41003065047122256
# differential_evolution step 635: f(x)= 0.41003065047122256
# differential_evolution step 636: f(x)= 0.41003065047122256
# differential_evolution step 637: f(x)= 0.41003065047122256
# differential_evolution step 638: f(x)= 0.41003065047122256
# differential_evolution step 639: f(x)= 0.4070451514131196
# differential_evolution step 640: f(x)= 0.4070451514131196
# differential_evolution step 641: f(x)= 0.4070451514131196
# differential_evolution step 642: f(x)= 0.4070451514131196
# differential_evolution step 643: f(x)= 0.4070451514131196
# differential_evolution step 644: f(x)= 0.4070451514131196
# differential_evolution step 645: f(x)= 0.4070451514131196
# differential_evolution step 646: f(x)= 0.4070451514131196
# differential_evolution step 647: f(x)= 0.4070451514131196
# differential_evolution step 648: f(x)= 0.4070451514131196
# differential_evolution step 649: f(x)= 0.39457429849759906
# differential_evolution step 650: f(x)= 0.39457429849759906
# differential_evolution step 651: f(x)= 0.39457429849759906
# differential_evolution step 652: f(x)= 0.39457429849759906
# differential_evolution step 653: f(x)= 0.39457429849759906
# differential_evolution step 654: f(x)= 0.39457429849759906
# differential_evolution step 655: f(x)= 0.39457429849759906
# differential_evolution step 656: f(x)= 0.39457429849759906
# differential_evolution step 657: f(x)= 0.39457429849759906
# differential_evolution step 658: f(x)= 0.39457429849759906
# differential_evolution step 659: f(x)= 0.39457429849759906
# differential_evolution step 660: f(x)= 0.39457429849759906
# differential_evolution step 661: f(x)= 0.39457429849759906
# differential_evolution step 662: f(x)= 0.39457429849759906
# differential_evolution step 663: f(x)= 0.39457429849759906
# differential_evolution step 664: f(x)= 0.39457429849759906
# differential_evolution step 665: f(x)= 0.39457429849759906
# differential_evolution step 666: f(x)= 0.39457429849759906
# differential_evolution step 667: f(x)= 0.39457429849759906
# differential_evolution step 668: f(x)= 0.39457429849759906
# differential_evolution step 669: f(x)= 0.39457429849759906
# differential_evolution step 670: f(x)= 0.39457429849759906
# differential_evolution step 671: f(x)= 0.39457429849759906
# differential_evolution step 672: f(x)= 0.39457429849759906
# differential_evolution step 673: f(x)= 0.39457429849759906
# differential_evolution step 674: f(x)= 0.39457429849759906
# differential_evolution step 675: f(x)= 0.39457429849759906
# differential_evolution step 676: f(x)= 0.39457429849759906
# differential_evolution step 677: f(x)= 0.39457429849759906
# differential_evolution step 678: f(x)= 0.39457429849759906
# differential_evolution step 679: f(x)= 0.39457429849759906
# differential_evolution step 680: f(x)= 0.39457429849759906
# differential_evolution step 681: f(x)= 0.39457429849759906
# differential_evolution step 682: f(x)= 0.39457429849759906
# differential_evolution step 683: f(x)= 0.39457429849759906
# differential_evolution step 684: f(x)= 0.39457429849759906
# differential_evolution step 685: f(x)= 0.39457429849759906
# differential_evolution step 686: f(x)= 0.39457429849759906
# differential_evolution step 687: f(x)= 0.39457429849759906
# differential_evolution step 688: f(x)= 0.39457429849759906
# differential_evolution step 689: f(x)= 0.39457429849759906
# differential_evolution step 690: f(x)= 0.39457429849759906
# differential_evolution step 691: f(x)= 0.39457429849759906
# differential_evolution step 692: f(x)= 0.39457429849759906
# differential_evolution step 693: f(x)= 0.39457429849759906
# differential_evolution step 694: f(x)= 0.39457429849759906
# differential_evolution step 695: f(x)= 0.39457429849759906
# differential_evolution step 696: f(x)= 0.39457429849759906
# differential_evolution step 697: f(x)= 0.39457429849759906
# differential_evolution step 698: f(x)= 0.39457429849759906
# differential_evolution step 699: f(x)= 0.39457429849759906
# differential_evolution step 700: f(x)= 0.391963726058827
# differential_evolution step 701: f(x)= 0.391963726058827
# differential_evolution step 702: f(x)= 0.391963726058827
# differential_evolution step 703: f(x)= 0.391963726058827
# differential_evolution step 704: f(x)= 0.391963726058827
# differential_evolution step 705: f(x)= 0.391963726058827
# differential_evolution step 706: f(x)= 0.391963726058827
# differential_evolution step 707: f(x)= 0.38795168094082194
# differential_evolution step 708: f(x)= 0.38795168094082194
# differential_evolution step 709: f(x)= 0.38795168094082194
# differential_evolution step 710: f(x)= 0.38795168094082194
# differential_evolution step 711: f(x)= 0.38795168094082194
# differential_evolution step 712: f(x)= 0.38795168094082194
# differential_evolution step 713: f(x)= 0.38795168094082194
# differential_evolution step 714: f(x)= 0.38795168094082194
# differential_evolution step 715: f(x)= 0.38795168094082194
# differential_evolution step 716: f(x)= 0.38795168094082194
# differential_evolution step 717: f(x)= 0.38795168094082194
# differential_evolution step 718: f(x)= 0.38795168094082194
# differential_evolution step 719: f(x)= 0.38795168094082194
# differential_evolution step 720: f(x)= 0.38795168094082194
# differential_evolution step 721: f(x)= 0.38795168094082194
# differential_evolution step 722: f(x)= 0.38795168094082194
# differential_evolution step 723: f(x)= 0.38795168094082194
# differential_evolution step 724: f(x)= 0.38795168094082194
# differential_evolution step 725: f(x)= 0.38795168094082194
# differential_evolution step 726: f(x)= 0.38795168094082194
# differential_evolution step 727: f(x)= 0.38795168094082194
# differential_evolution step 728: f(x)= 0.38795168094082194
# differential_evolution step 729: f(x)= 0.38795168094082194
# differential_evolution step 730: f(x)= 0.38795168094082194
# differential_evolution step 731: f(x)= 0.38795168094082194
# differential_evolution step 732: f(x)= 0.38795168094082194
# differential_evolution step 733: f(x)= 0.38795168094082194
# differential_evolution step 734: f(x)= 0.38795168094082194
# differential_evolution step 735: f(x)= 0.38795168094082194
# differential_evolution step 736: f(x)= 0.38795168094082194
# differential_evolution step 737: f(x)= 0.38795168094082194
# differential_evolution step 738: f(x)= 0.38795168094082194
# differential_evolution step 739: f(x)= 0.38795168094082194
# differential_evolution step 740: f(x)= 0.38296013255353917
# differential_evolution step 741: f(x)= 0.38296013255353917
# differential_evolution step 742: f(x)= 0.38296013255353917
# differential_evolution step 743: f(x)= 0.38296013255353917
# differential_evolution step 744: f(x)= 0.38296013255353917
# differential_evolution step 745: f(x)= 0.38296013255353917
# differential_evolution step 746: f(x)= 0.38296013255353917
# differential_evolution step 747: f(x)= 0.38296013255353917
# differential_evolution step 748: f(x)= 0.38296013255353917
# differential_evolution step 749: f(x)= 0.38296013255353917
# differential_evolution step 750: f(x)= 0.38296013255353917
# differential_evolution step 751: f(x)= 0.38296013255353917
# differential_evolution step 752: f(x)= 0.38296013255353917
# differential_evolution step 753: f(x)= 0.38296013255353917
# differential_evolution step 754: f(x)= 0.38296013255353917
# differential_evolution step 755: f(x)= 0.38296013255353917
# differential_evolution step 756: f(x)= 0.38296013255353917
# differential_evolution step 757: f(x)= 0.38296013255353917
# differential_evolution step 758: f(x)= 0.38296013255353917
# differential_evolution step 759: f(x)= 0.38296013255353917
# differential_evolution step 760: f(x)= 0.38296013255353917
# differential_evolution step 761: f(x)= 0.38296013255353917
# differential_evolution step 762: f(x)= 0.38296013255353917
# differential_evolution step 763: f(x)= 0.38296013255353917
# differential_evolution step 764: f(x)= 0.38296013255353917
# differential_evolution step 765: f(x)= 0.38296013255353917
# differential_evolution step 766: f(x)= 0.38296013255353917
# differential_evolution step 767: f(x)= 0.38296013255353917
# differential_evolution step 768: f(x)= 0.38296013255353917
# differential_evolution step 769: f(x)= 0.38020801045011965
# differential_evolution step 770: f(x)= 0.38020801045011965
# differential_evolution step 771: f(x)= 0.38020801045011965
# differential_evolution step 772: f(x)= 0.38020801045011965
# differential_evolution step 773: f(x)= 0.38008219587287406
# differential_evolution step 774: f(x)= 0.38008219587287406
# differential_evolution step 775: f(x)= 0.38008219587287406
# differential_evolution step 776: f(x)= 0.37381923367499315
# differential_evolution step 777: f(x)= 0.37381923367499315
# differential_evolution step 778: f(x)= 0.37381923367499315
# differential_evolution step 779: f(x)= 0.37381923367499315
# differential_evolution step 780: f(x)= 0.37381923367499315
# differential_evolution step 781: f(x)= 0.37381923367499315
# differential_evolution step 782: f(x)= 0.37381923367499315
# differential_evolution step 783: f(x)= 0.37381923367499315
# differential_evolution step 784: f(x)= 0.37381923367499315
# differential_evolution step 785: f(x)= 0.37381923367499315
# differential_evolution step 786: f(x)= 0.37381923367499315
# differential_evolution step 787: f(x)= 0.37381923367499315
# differential_evolution step 788: f(x)= 0.37381923367499315
# differential_evolution step 789: f(x)= 0.37381923367499315
# differential_evolution step 790: f(x)= 0.37381923367499315
# differential_evolution step 791: f(x)= 0.37381923367499315
# differential_evolution step 792: f(x)= 0.37381923367499315
# differential_evolution step 793: f(x)= 0.37381923367499315
# differential_evolution step 794: f(x)= 0.37381923367499315
# differential_evolution step 795: f(x)= 0.37381923367499315
# differential_evolution step 796: f(x)= 0.37381923367499315
# differential_evolution step 797: f(x)= 0.37381923367499315
# differential_evolution step 798: f(x)= 0.37381923367499315
# differential_evolution step 799: f(x)= 0.37381923367499315
# differential_evolution step 800: f(x)= 0.37381923367499315
# differential_evolution step 801: f(x)= 0.37381923367499315
# differential_evolution step 802: f(x)= 0.37381923367499315
# differential_evolution step 803: f(x)= 0.37381923367499315
# differential_evolution step 804: f(x)= 0.37381923367499315
# differential_evolution step 805: f(x)= 0.37381923367499315
# differential_evolution step 806: f(x)= 0.37381923367499315
# differential_evolution step 807: f(x)= 0.37381923367499315
# differential_evolution step 808: f(x)= 0.37381923367499315
# differential_evolution step 809: f(x)= 0.37381923367499315
# differential_evolution step 810: f(x)= 0.37381923367499315
# differential_evolution step 811: f(x)= 0.37381923367499315
# differential_evolution step 812: f(x)= 0.37381923367499315
# differential_evolution step 813: f(x)= 0.37381923367499315
# differential_evolution step 814: f(x)= 0.37381923367499315
# differential_evolution step 815: f(x)= 0.37381923367499315
# differential_evolution step 816: f(x)= 0.37381923367499315
# differential_evolution step 817: f(x)= 0.37381923367499315
# differential_evolution step 818: f(x)= 0.37381923367499315
# differential_evolution step 819: f(x)= 0.37381923367499315
# differential_evolution step 820: f(x)= 0.37381923367499315
# differential_evolution step 821: f(x)= 0.36993381659864377
# differential_evolution step 822: f(x)= 0.36993381659864377
# differential_evolution step 823: f(x)= 0.36993381659864377
# differential_evolution step 824: f(x)= 0.36993381659864377
# differential_evolution step 825: f(x)= 0.36993381659864377
# differential_evolution step 826: f(x)= 0.36993381659864377
# differential_evolution step 827: f(x)= 0.36993381659864377
# differential_evolution step 828: f(x)= 0.36993381659864377
# differential_evolution step 829: f(x)= 0.36993381659864377
# differential_evolution step 830: f(x)= 0.36993381659864377
# differential_evolution step 831: f(x)= 0.36993381659864377
# differential_evolution step 832: f(x)= 0.36993381659864377
# differential_evolution step 833: f(x)= 0.36993381659864377
# differential_evolution step 834: f(x)= 0.36993381659864377
# differential_evolution step 835: f(x)= 0.36993381659864377
# differential_evolution step 836: f(x)= 0.36993381659864377
# differential_evolution step 837: f(x)= 0.36993381659864377
# differential_evolution step 838: f(x)= 0.36993381659864377
# differential_evolution step 839: f(x)= 0.36993381659864377
# differential_evolution step 840: f(x)= 0.36993381659864377
# differential_evolution step 841: f(x)= 0.36993381659864377
# differential_evolution step 842: f(x)= 0.36993381659864377
# differential_evolution step 843: f(x)= 0.36993381659864377
# differential_evolution step 844: f(x)= 0.36993381659864377
# differential_evolution step 845: f(x)= 0.36993381659864377
# differential_evolution step 846: f(x)= 0.36993381659864377
# differential_evolution step 847: f(x)= 0.36993381659864377
# differential_evolution step 848: f(x)= 0.36993381659864377
# differential_evolution step 849: f(x)= 0.36993381659864377
# differential_evolution step 850: f(x)= 0.36993381659864377
# differential_evolution step 851: f(x)= 0.36993381659864377
# differential_evolution step 852: f(x)= 0.36993381659864377
# differential_evolution step 853: f(x)= 0.36418073470942874
# differential_evolution step 854: f(x)= 0.36418073470942874
# differential_evolution step 855: f(x)= 0.35972776750832974
# differential_evolution step 856: f(x)= 0.35972776750832974
# differential_evolution step 857: f(x)= 0.35972776750832974
# differential_evolution step 858: f(x)= 0.35972776750832974
# differential_evolution step 859: f(x)= 0.35972776750832974
# differential_evolution step 860: f(x)= 0.35972776750832974
# differential_evolution step 861: f(x)= 0.35972776750832974
# differential_evolution step 862: f(x)= 0.35972776750832974
# differential_evolution step 863: f(x)= 0.35972776750832974
# differential_evolution step 864: f(x)= 0.35972776750832974
# differential_evolution step 865: f(x)= 0.35972776750832974
# differential_evolution step 866: f(x)= 0.35972776750832974
# differential_evolution step 867: f(x)= 0.35972776750832974
# differential_evolution step 868: f(x)= 0.35972776750832974
# differential_evolution step 869: f(x)= 0.35972776750832974
# differential_evolution step 870: f(x)= 0.35972776750832974
# differential_evolution step 871: f(x)= 0.35972776750832974
# differential_evolution step 872: f(x)= 0.35972776750832974
# differential_evolution step 873: f(x)= 0.35972776750832974
# differential_evolution step 874: f(x)= 0.35972776750832974
# differential_evolution step 875: f(x)= 0.35972776750832974
# differential_evolution step 876: f(x)= 0.35972776750832974
# differential_evolution step 877: f(x)= 0.35972776750832974
# differential_evolution step 878: f(x)= 0.35972776750832974
# differential_evolution step 879: f(x)= 0.35972776750832974
# differential_evolution step 880: f(x)= 0.35972776750832974
# differential_evolution step 881: f(x)= 0.35972776750832974
# differential_evolution step 882: f(x)= 0.35972776750832974
# differential_evolution step 883: f(x)= 0.35972776750832974
# differential_evolution step 884: f(x)= 0.35972776750832974
# differential_evolution step 885: f(x)= 0.35809856288528774
# differential_evolution step 886: f(x)= 0.35809856288528774
# differential_evolution step 887: f(x)= 0.35809856288528774
# differential_evolution step 888: f(x)= 0.35809856288528774
# differential_evolution step 889: f(x)= 0.35809856288528774
# differential_evolution step 890: f(x)= 0.35809856288528774
# differential_evolution step 891: f(x)= 0.35809856288528774
# differential_evolution step 892: f(x)= 0.35809856288528774
# differential_evolution step 893: f(x)= 0.35809856288528774
# differential_evolution step 894: f(x)= 0.35809856288528774
# differential_evolution step 895: f(x)= 0.35809856288528774
# differential_evolution step 896: f(x)= 0.35809856288528774
# differential_evolution step 897: f(x)= 0.35809856288528774
# differential_evolution step 898: f(x)= 0.35809856288528774
# differential_evolution step 899: f(x)= 0.35809856288528774
# differential_evolution step 900: f(x)= 0.35809856288528774
# differential_evolution step 901: f(x)= 0.35809856288528774
# differential_evolution step 902: f(x)= 0.35809856288528774
# differential_evolution step 903: f(x)= 0.35809856288528774
# differential_evolution step 904: f(x)= 0.35809856288528774
# differential_evolution step 905: f(x)= 0.35809856288528774
# differential_evolution step 906: f(x)= 0.35809856288528774
# differential_evolution step 907: f(x)= 0.35809856288528774
# differential_evolution step 908: f(x)= 0.35780021741445395
# differential_evolution step 909: f(x)= 0.35780021741445395
# differential_evolution step 910: f(x)= 0.35754684073519244
# differential_evolution step 911: f(x)= 0.35754684073519244
# differential_evolution step 912: f(x)= 0.3529821066342574
# differential_evolution step 913: f(x)= 0.3529821066342574
# differential_evolution step 914: f(x)= 0.3529821066342574
# differential_evolution step 915: f(x)= 0.3529821066342574
# differential_evolution step 916: f(x)= 0.3529821066342574
# differential_evolution step 917: f(x)= 0.3529821066342574
# differential_evolution step 918: f(x)= 0.3529821066342574
# differential_evolution step 919: f(x)= 0.3529821066342574
# differential_evolution step 920: f(x)= 0.3529821066342574
# differential_evolution step 921: f(x)= 0.3529821066342574
# differential_evolution step 922: f(x)= 0.3529821066342574
# differential_evolution step 923: f(x)= 0.3529821066342574
# differential_evolution step 924: f(x)= 0.3529821066342574
# differential_evolution step 925: f(x)= 0.3529821066342574
# differential_evolution step 926: f(x)= 0.3529821066342574
# differential_evolution step 927: f(x)= 0.3529821066342574
# differential_evolution step 928: f(x)= 0.3529821066342574
# differential_evolution step 929: f(x)= 0.3529821066342574
# differential_evolution step 930: f(x)= 0.3529821066342574
# differential_evolution step 931: f(x)= 0.3529821066342574
# differential_evolution step 932: f(x)= 0.3529821066342574
# differential_evolution step 933: f(x)= 0.3529821066342574
# differential_evolution step 934: f(x)= 0.3529821066342574
# differential_evolution step 935: f(x)= 0.3529821066342574
# differential_evolution step 936: f(x)= 0.3529821066342574
# differential_evolution step 937: f(x)= 0.35001951090579186
# differential_evolution step 938: f(x)= 0.35001951090579186
# differential_evolution step 939: f(x)= 0.35001951090579186
# differential_evolution step 940: f(x)= 0.35001951090579186
# differential_evolution step 941: f(x)= 0.35001951090579186
# differential_evolution step 942: f(x)= 0.35001951090579186
# differential_evolution step 943: f(x)= 0.35001951090579186
# differential_evolution step 944: f(x)= 0.35001951090579186
# differential_evolution step 945: f(x)= 0.35001951090579186
# differential_evolution step 946: f(x)= 0.35001951090579186
# differential_evolution step 947: f(x)= 0.35001951090579186
# differential_evolution step 948: f(x)= 0.35001951090579186
# differential_evolution step 949: f(x)= 0.35001951090579186
# differential_evolution step 950: f(x)= 0.35001951090579186
# differential_evolution step 951: f(x)= 0.35001951090579186
# differential_evolution step 952: f(x)= 0.35001951090579186
# differential_evolution step 953: f(x)= 0.35001951090579186
# differential_evolution step 954: f(x)= 0.35001951090579186
# differential_evolution step 955: f(x)= 0.35001951090579186
# differential_evolution step 956: f(x)= 0.35001951090579186
# differential_evolution step 957: f(x)= 0.35001951090579186
# differential_evolution step 958: f(x)= 0.35001951090579186
# differential_evolution step 959: f(x)= 0.35001951090579186
# differential_evolution step 960: f(x)= 0.35001951090579186
# differential_evolution step 961: f(x)= 0.35001951090579186
# differential_evolution step 962: f(x)= 0.35001951090579186
# differential_evolution step 963: f(x)= 0.35001951090579186
# differential_evolution step 964: f(x)= 0.35001951090579186
# differential_evolution step 965: f(x)= 0.34663458290228266
# differential_evolution step 966: f(x)= 0.34663458290228266
# differential_evolution step 967: f(x)= 0.34663458290228266
# differential_evolution step 968: f(x)= 0.34663458290228266
# differential_evolution step 969: f(x)= 0.34663458290228266
# differential_evolution step 970: f(x)= 0.34663458290228266
# differential_evolution step 971: f(x)= 0.34663458290228266
# differential_evolution step 972: f(x)= 0.3447267671956677
# differential_evolution step 973: f(x)= 0.3447267671956677
# differential_evolution step 974: f(x)= 0.3447267671956677
# differential_evolution step 975: f(x)= 0.3447267671956677
# differential_evolution step 976: f(x)= 0.3447267671956677
# differential_evolution step 977: f(x)= 0.3447267671956677
# differential_evolution step 978: f(x)= 0.3447267671956677
# differential_evolution step 979: f(x)= 0.3447267671956677
# differential_evolution step 980: f(x)= 0.3447267671956677
# differential_evolution step 981: f(x)= 0.3447267671956677
# differential_evolution step 982: f(x)= 0.3447267671956677
# differential_evolution step 983: f(x)= 0.3447267671956677
# differential_evolution step 984: f(x)= 0.3447267671956677
# differential_evolution step 985: f(x)= 0.3447267671956677
# differential_evolution step 986: f(x)= 0.3447267671956677
# differential_evolution step 987: f(x)= 0.3447267671956677
# differential_evolution step 988: f(x)= 0.3447267671956677
# differential_evolution step 989: f(x)= 0.3447267671956677
# differential_evolution step 990: f(x)= 0.3447267671956677
# differential_evolution step 991: f(x)= 0.3447267671956677
# differential_evolution step 992: f(x)= 0.3447267671956677
# differential_evolution step 993: f(x)= 0.3447267671956677
# differential_evolution step 994: f(x)= 0.3447267671956677
# differential_evolution step 995: f(x)= 0.3447267671956677
# differential_evolution step 996: f(x)= 0.3447267671956677
# differential_evolution step 997: f(x)= 0.3447267671956677
# differential_evolution step 998: f(x)= 0.3447267671956677
# differential_evolution step 999: f(x)= 0.3447267671956677
# differential_evolution step 1000: f(x)= 0.3447267671956677
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [2.93522720e-01 4.04215961e+00 2.82853691e+00 2.88162041e+01
#  1.27022749e-01 7.96908412e+00 1.99006310e+00 5.69909482e+01
#  1.35930514e-01 1.60211725e+01 1.63256096e+00 7.74446081e+01
#  9.53057487e-03 1.22911897e+01 5.03383842e+00 8.30000000e+01
#  1.09509733e-01 8.38827536e+00 1.40028129e+00 1.42944706e+01]
# Chi quadro minimo: 0.3372283892163406

# %%
# Plots:
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\2384567265.py:11: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2767, r_e=4.4107, n=2.8108, x_0=28.8162
# Sérsic 2: I_e=0.0810, r_e=11.7250, n=2.2757, x_0=57.0396
# Sérsic 3: I_e=0.1513, r_e=13.8219, n=1.5828, x_0=77.3796
# Sérsic 4: I_e=0.0110, r_e=8.9110, n=5.4461, x_0=83.0498
# Sérsic 5: I_e=0.1078, r_e=7.8454, n=1.4474, x_0=14.3292
# [2.84012340e-01 2.39825522e+00 2.49972722e+00 8.72864744e-04
#  6.00871879e-02 6.55187331e+00 5.82517495e-01 8.53940708e-02
#  6.47977414e-02 5.19632243e+00 3.06208250e-01 1.97622654e-01
#  1.77954113e-01 9.02351545e+01 1.68580119e+01 1.06978027e-01
#  4.75687920e-02 2.39924405e+00 3.30300757e-01 1.47848572e-01]
# 29.53654881007369
# 80.16946020247876 29.53654881007369 121.63995252983554 20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
   (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (75, 79),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (80, 85),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 16),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 73)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 43833.26035457132
# differential_evolution step 2: f(x)= 18501.972358982897
# differential_evolution step 3: f(x)= 18501.972358982897
# differential_evolution step 4: f(x)= 18501.972358982897
# differential_evolution step 5: f(x)= 18501.972358982897
# differential_evolution step 6: f(x)= 18501.972358982897
# differential_evolution step 7: f(x)= 18501.972358982897
# differential_evolution step 8: f(x)= 18501.972358982897
# differential_evolution step 9: f(x)= 16141.353231271945
# differential_evolution step 10: f(x)= 2390.4604475123742
# differential_evolution step 11: f(x)= 1775.108522380171
# differential_evolution step 12: f(x)= 1775.108522380171
# differential_evolution step 13: f(x)= 1775.108522380171
# differential_evolution step 14: f(x)= 1775.108522380171
# differential_evolution step 15: f(x)= 711.3389799442107
# differential_evolution step 16: f(x)= 711.3389799442107
# differential_evolution step 17: f(x)= 430.68151482010694
# differential_evolution step 18: f(x)= 430.68151482010694
# differential_evolution step 19: f(x)= 430.68151482010694
# differential_evolution step 20: f(x)= 430.68151482010694
# differential_evolution step 21: f(x)= 265.7285132517906
# differential_evolution step 22: f(x)= 265.7285132517906
# differential_evolution step 23: f(x)= 265.7285132517906
# differential_evolution step 24: f(x)= 120.18756854491485
# differential_evolution step 25: f(x)= 120.18756854491485
# differential_evolution step 26: f(x)= 120.18756854491485
# differential_evolution step 27: f(x)= 120.18756854491485
# differential_evolution step 28: f(x)= 120.18756854491485
# differential_evolution step 29: f(x)= 120.18756854491485
# differential_evolution step 30: f(x)= 67.90217083483705
# differential_evolution step 31: f(x)= 67.90217083483705
# differential_evolution step 32: f(x)= 67.90217083483705
# differential_evolution step 33: f(x)= 67.90217083483705
# differential_evolution step 34: f(x)= 67.90217083483705
# differential_evolution step 35: f(x)= 67.90217083483705
# differential_evolution step 36: f(x)= 67.90217083483705
# differential_evolution step 37: f(x)= 67.90217083483705
# differential_evolution step 38: f(x)= 67.90217083483705
# differential_evolution step 39: f(x)= 67.90217083483705
# differential_evolution step 40: f(x)= 67.90217083483705
# differential_evolution step 41: f(x)= 67.90217083483705
# differential_evolution step 42: f(x)= 67.90217083483705
# differential_evolution step 43: f(x)= 67.90217083483705
# differential_evolution step 44: f(x)= 67.90217083483705
# differential_evolution step 45: f(x)= 67.90217083483705
# differential_evolution step 46: f(x)= 67.90217083483705
# differential_evolution step 47: f(x)= 67.90217083483705
# differential_evolution step 48: f(x)= 67.90217083483705
# differential_evolution step 49: f(x)= 67.90217083483705
# differential_evolution step 50: f(x)= 67.90217083483705
# differential_evolution step 51: f(x)= 67.90217083483705
# differential_evolution step 52: f(x)= 67.90217083483705
# differential_evolution step 53: f(x)= 67.90217083483705
# differential_evolution step 54: f(x)= 67.90217083483705
# differential_evolution step 55: f(x)= 64.95701084410321
# differential_evolution step 56: f(x)= 64.95701084410321
# differential_evolution step 57: f(x)= 64.95701084410321
# differential_evolution step 58: f(x)= 64.95701084410321
# differential_evolution step 59: f(x)= 64.95701084410321
# differential_evolution step 60: f(x)= 52.91578185702102
# differential_evolution step 61: f(x)= 52.91578185702102
# differential_evolution step 62: f(x)= 52.91578185702102
# differential_evolution step 63: f(x)= 52.91578185702102
# differential_evolution step 64: f(x)= 52.91578185702102
# differential_evolution step 65: f(x)= 52.91578185702102
# differential_evolution step 66: f(x)= 52.91578185702102
# differential_evolution step 67: f(x)= 46.79000673760272
# differential_evolution step 68: f(x)= 46.79000673760272
# differential_evolution step 69: f(x)= 46.79000673760272
# differential_evolution step 70: f(x)= 46.79000673760272
# differential_evolution step 71: f(x)= 46.79000673760272
# differential_evolution step 72: f(x)= 46.79000673760272
# differential_evolution step 73: f(x)= 38.78837919279119
# differential_evolution step 74: f(x)= 38.78837919279119
# differential_evolution step 75: f(x)= 38.78837919279119
# differential_evolution step 76: f(x)= 20.237524760260936
# differential_evolution step 77: f(x)= 20.237524760260936
# differential_evolution step 78: f(x)= 20.237524760260936
# differential_evolution step 79: f(x)= 20.237524760260936
# differential_evolution step 80: f(x)= 20.237524760260936
# differential_evolution step 81: f(x)= 20.237524760260936
# differential_evolution step 82: f(x)= 20.237524760260936
# differential_evolution step 83: f(x)= 20.237524760260936
# differential_evolution step 84: f(x)= 20.237524760260936
# differential_evolution step 85: f(x)= 20.237524760260936
# differential_evolution step 86: f(x)= 20.237524760260936
# differential_evolution step 87: f(x)= 20.237524760260936
# differential_evolution step 88: f(x)= 20.237524760260936
# differential_evolution step 89: f(x)= 20.237524760260936
# differential_evolution step 90: f(x)= 20.237524760260936
# differential_evolution step 91: f(x)= 20.237524760260936
# differential_evolution step 92: f(x)= 20.237524760260936
# differential_evolution step 93: f(x)= 20.237524760260936
# differential_evolution step 94: f(x)= 20.237524760260936
# differential_evolution step 95: f(x)= 20.237524760260936
# differential_evolution step 96: f(x)= 20.237524760260936
# differential_evolution step 97: f(x)= 12.672930163077277
# differential_evolution step 98: f(x)= 12.672930163077277
# differential_evolution step 99: f(x)= 12.672930163077277
# differential_evolution step 100: f(x)= 12.672930163077277
# differential_evolution step 101: f(x)= 12.672930163077277
# differential_evolution step 102: f(x)= 12.672930163077277
# differential_evolution step 103: f(x)= 12.672930163077277
# differential_evolution step 104: f(x)= 12.672930163077277
# differential_evolution step 105: f(x)= 12.672930163077277
# differential_evolution step 106: f(x)= 12.672930163077277
# differential_evolution step 107: f(x)= 12.672930163077277
# differential_evolution step 108: f(x)= 12.672930163077277
# differential_evolution step 109: f(x)= 10.001769792979674
# differential_evolution step 110: f(x)= 10.001769792979674
# differential_evolution step 111: f(x)= 10.001769792979674
# differential_evolution step 112: f(x)= 10.001769792979674
# differential_evolution step 113: f(x)= 10.001769792979674
# differential_evolution step 114: f(x)= 10.001769792979674
# differential_evolution step 115: f(x)= 10.001769792979674
# differential_evolution step 116: f(x)= 10.001769792979674
# differential_evolution step 117: f(x)= 10.001769792979674
# differential_evolution step 118: f(x)= 10.001769792979674
# differential_evolution step 119: f(x)= 10.001769792979674
# differential_evolution step 120: f(x)= 10.001769792979674
# differential_evolution step 121: f(x)= 10.001769792979674
# differential_evolution step 122: f(x)= 10.001769792979674
# differential_evolution step 123: f(x)= 10.001769792979674
# differential_evolution step 124: f(x)= 10.001769792979674
# differential_evolution step 125: f(x)= 10.001769792979674
# differential_evolution step 126: f(x)= 9.61920518484446
# differential_evolution step 127: f(x)= 9.61920518484446
# differential_evolution step 128: f(x)= 9.61920518484446
# differential_evolution step 129: f(x)= 9.61920518484446
# differential_evolution step 130: f(x)= 9.61920518484446
# differential_evolution step 131: f(x)= 9.61920518484446
# differential_evolution step 132: f(x)= 8.692630086537903
# differential_evolution step 133: f(x)= 8.692630086537903
# differential_evolution step 134: f(x)= 8.692630086537903
# differential_evolution step 135: f(x)= 8.692630086537903
# differential_evolution step 136: f(x)= 7.852153406138749
# differential_evolution step 137: f(x)= 7.852153406138749
# differential_evolution step 138: f(x)= 7.852153406138749
# differential_evolution step 139: f(x)= 7.852153406138749
# differential_evolution step 140: f(x)= 7.852153406138749
# differential_evolution step 141: f(x)= 7.852153406138749
# differential_evolution step 142: f(x)= 7.852153406138749
# differential_evolution step 143: f(x)= 7.431756828497078
# differential_evolution step 144: f(x)= 7.431756828497078
# differential_evolution step 145: f(x)= 7.431756828497078
# differential_evolution step 146: f(x)= 6.8409441933402375
# differential_evolution step 147: f(x)= 6.8409441933402375
# differential_evolution step 148: f(x)= 6.8409441933402375
# differential_evolution step 149: f(x)= 6.8409441933402375
# differential_evolution step 150: f(x)= 6.8409441933402375
# differential_evolution step 151: f(x)= 6.8409441933402375
# differential_evolution step 152: f(x)= 5.598637724953116
# differential_evolution step 153: f(x)= 5.598637724953116
# differential_evolution step 154: f(x)= 5.598637724953116
# differential_evolution step 155: f(x)= 5.598637724953116
# differential_evolution step 156: f(x)= 5.598637724953116
# differential_evolution step 157: f(x)= 5.090371470187716
# differential_evolution step 158: f(x)= 5.090371470187716
# differential_evolution step 159: f(x)= 5.090371470187716
# differential_evolution step 160: f(x)= 5.090371470187716
# differential_evolution step 161: f(x)= 5.090371470187716
# differential_evolution step 162: f(x)= 4.8276904207442435
# differential_evolution step 163: f(x)= 4.8276904207442435
# differential_evolution step 164: f(x)= 4.8276904207442435
# differential_evolution step 165: f(x)= 4.8276904207442435
# differential_evolution step 166: f(x)= 4.8276904207442435
# differential_evolution step 167: f(x)= 4.8276904207442435
# differential_evolution step 168: f(x)= 4.8276904207442435
# differential_evolution step 169: f(x)= 4.8276904207442435
# differential_evolution step 170: f(x)= 4.8276904207442435
# differential_evolution step 171: f(x)= 4.8276904207442435
# differential_evolution step 172: f(x)= 4.8276904207442435
# differential_evolution step 173: f(x)= 4.8276904207442435
# differential_evolution step 174: f(x)= 4.8276904207442435
# differential_evolution step 175: f(x)= 4.8276904207442435
# differential_evolution step 176: f(x)= 4.333103425959707
# differential_evolution step 177: f(x)= 4.333103425959707
# differential_evolution step 178: f(x)= 4.333103425959707
# differential_evolution step 179: f(x)= 4.333103425959707
# differential_evolution step 180: f(x)= 4.333103425959707
# differential_evolution step 181: f(x)= 4.333103425959707
# differential_evolution step 182: f(x)= 4.333103425959707
# differential_evolution step 183: f(x)= 4.333103425959707
# differential_evolution step 184: f(x)= 3.7097718738272247
# differential_evolution step 185: f(x)= 3.7097718738272247
# differential_evolution step 186: f(x)= 3.7097718738272247
# differential_evolution step 187: f(x)= 3.7097718738272247
# differential_evolution step 188: f(x)= 3.7097718738272247
# differential_evolution step 189: f(x)= 3.7097718738272247
# differential_evolution step 190: f(x)= 3.7097718738272247
# differential_evolution step 191: f(x)= 3.7097718738272247
# differential_evolution step 192: f(x)= 3.7097718738272247
# differential_evolution step 193: f(x)= 3.7097718738272247
# differential_evolution step 194: f(x)= 3.7097718738272247
# differential_evolution step 195: f(x)= 3.7097718738272247
# differential_evolution step 196: f(x)= 3.7097718738272247
# differential_evolution step 197: f(x)= 3.7097718738272247
# differential_evolution step 198: f(x)= 3.7097718738272247
# differential_evolution step 199: f(x)= 3.7097718738272247
# differential_evolution step 200: f(x)= 3.7097718738272247
# differential_evolution step 201: f(x)= 3.7097718738272247
# differential_evolution step 202: f(x)= 3.7097718738272247
# differential_evolution step 203: f(x)= 3.7097718738272247
# differential_evolution step 204: f(x)= 3.7097718738272247
# differential_evolution step 205: f(x)= 3.7097718738272247
# differential_evolution step 206: f(x)= 3.3456645567938486
# differential_evolution step 207: f(x)= 3.129489259898935
# differential_evolution step 208: f(x)= 3.129489259898935
# differential_evolution step 209: f(x)= 3.129489259898935
# differential_evolution step 210: f(x)= 3.129489259898935
# differential_evolution step 211: f(x)= 2.9299059395957694
# differential_evolution step 212: f(x)= 2.9299059395957694
# differential_evolution step 213: f(x)= 2.9051930512791784
# differential_evolution step 214: f(x)= 2.9051930512791784
# differential_evolution step 215: f(x)= 2.9051930512791784
# differential_evolution step 216: f(x)= 2.9051930512791784
# differential_evolution step 217: f(x)= 2.9051930512791784
# differential_evolution step 218: f(x)= 2.9051930512791784
# differential_evolution step 219: f(x)= 2.9051930512791784
# differential_evolution step 220: f(x)= 2.619665608888714
# differential_evolution step 221: f(x)= 2.619665608888714
# differential_evolution step 222: f(x)= 2.5596273351749037
# differential_evolution step 223: f(x)= 2.5596273351749037
# differential_evolution step 224: f(x)= 2.5596273351749037
# differential_evolution step 225: f(x)= 2.5596273351749037
# differential_evolution step 226: f(x)= 2.5596273351749037
# differential_evolution step 227: f(x)= 2.5596273351749037
# differential_evolution step 228: f(x)= 2.5596273351749037
# differential_evolution step 229: f(x)= 2.5596273351749037
# differential_evolution step 230: f(x)= 2.5596273351749037
# differential_evolution step 231: f(x)= 2.5596273351749037
# differential_evolution step 232: f(x)= 2.5596273351749037
# differential_evolution step 233: f(x)= 2.5596273351749037
# differential_evolution step 234: f(x)= 2.5596273351749037
# differential_evolution step 235: f(x)= 2.2047379728837924
# differential_evolution step 236: f(x)= 2.2047379728837924
# differential_evolution step 237: f(x)= 2.2047379728837924
# differential_evolution step 238: f(x)= 2.073800244422857
# differential_evolution step 239: f(x)= 2.073800244422857
# differential_evolution step 240: f(x)= 2.073800244422857
# differential_evolution step 241: f(x)= 2.073800244422857
# differential_evolution step 242: f(x)= 2.073800244422857
# differential_evolution step 243: f(x)= 1.8177219410241114
# differential_evolution step 244: f(x)= 1.8177219410241114
# differential_evolution step 245: f(x)= 1.8177219410241114
# differential_evolution step 246: f(x)= 1.8177219410241114
# differential_evolution step 247: f(x)= 1.8177219410241114
# differential_evolution step 248: f(x)= 1.8177219410241114
# differential_evolution step 249: f(x)= 1.8177219410241114
# differential_evolution step 250: f(x)= 1.8177219410241114
# differential_evolution step 251: f(x)= 1.8177219410241114
# differential_evolution step 252: f(x)= 1.7335271268711505
# differential_evolution step 253: f(x)= 1.7335271268711505
# differential_evolution step 254: f(x)= 1.7335271268711505
# differential_evolution step 255: f(x)= 1.7335271268711505
# differential_evolution step 256: f(x)= 1.7335271268711505
# differential_evolution step 257: f(x)= 1.7335271268711505
# differential_evolution step 258: f(x)= 1.7335271268711505
# differential_evolution step 259: f(x)= 1.7335271268711505
# differential_evolution step 260: f(x)= 1.7335271268711505
# differential_evolution step 261: f(x)= 1.7335271268711505
# differential_evolution step 262: f(x)= 1.7335271268711505
# differential_evolution step 263: f(x)= 1.7335271268711505
# differential_evolution step 264: f(x)= 1.7335271268711505
# differential_evolution step 265: f(x)= 1.7335271268711505
# differential_evolution step 266: f(x)= 1.4573773865398627
# differential_evolution step 267: f(x)= 1.4573773865398627
# differential_evolution step 268: f(x)= 1.4573773865398627
# differential_evolution step 269: f(x)= 1.4573773865398627
# differential_evolution step 270: f(x)= 1.4573773865398627
# differential_evolution step 271: f(x)= 1.4573773865398627
# differential_evolution step 272: f(x)= 1.4573773865398627
# differential_evolution step 273: f(x)= 1.4573773865398627
# differential_evolution step 274: f(x)= 1.4573773865398627
# differential_evolution step 275: f(x)= 1.4573773865398627
# differential_evolution step 276: f(x)= 1.4573773865398627
# differential_evolution step 277: f(x)= 1.4573773865398627
# differential_evolution step 278: f(x)= 1.4573773865398627
# differential_evolution step 279: f(x)= 1.4573773865398627
# differential_evolution step 280: f(x)= 1.4573773865398627
# differential_evolution step 281: f(x)= 1.4573773865398627
# differential_evolution step 282: f(x)= 1.4573773865398627
# differential_evolution step 283: f(x)= 1.3691523532944072
# differential_evolution step 284: f(x)= 1.3691523532944072
# differential_evolution step 285: f(x)= 1.3691523532944072
# differential_evolution step 286: f(x)= 1.3691523532944072
# differential_evolution step 287: f(x)= 1.3691523532944072
# differential_evolution step 288: f(x)= 1.3691523532944072
# differential_evolution step 289: f(x)= 1.3691523532944072
# differential_evolution step 290: f(x)= 1.3691523532944072
# differential_evolution step 291: f(x)= 1.3691523532944072
# differential_evolution step 292: f(x)= 1.3691523532944072
# differential_evolution step 293: f(x)= 1.3373477634454851
# differential_evolution step 294: f(x)= 1.3373477634454851
# differential_evolution step 295: f(x)= 1.3373477634454851
# differential_evolution step 296: f(x)= 1.3373477634454851
# differential_evolution step 297: f(x)= 1.3373477634454851
# differential_evolution step 298: f(x)= 1.3373477634454851
# differential_evolution step 299: f(x)= 1.3373477634454851
# differential_evolution step 300: f(x)= 1.3373477634454851
# differential_evolution step 301: f(x)= 1.3373477634454851
# differential_evolution step 302: f(x)= 1.3373477634454851
# differential_evolution step 303: f(x)= 1.3373477634454851
# differential_evolution step 304: f(x)= 1.3373477634454851
# differential_evolution step 305: f(x)= 1.3373477634454851
# differential_evolution step 306: f(x)= 1.3373477634454851
# differential_evolution step 307: f(x)= 1.3373477634454851
# differential_evolution step 308: f(x)= 1.3373477634454851
# differential_evolution step 309: f(x)= 1.078853186097544
# differential_evolution step 310: f(x)= 1.078853186097544
# differential_evolution step 311: f(x)= 1.0068491209257149
# differential_evolution step 312: f(x)= 1.0068491209257149
# differential_evolution step 313: f(x)= 1.0068491209257149
# differential_evolution step 314: f(x)= 1.0068491209257149
# differential_evolution step 315: f(x)= 1.0068491209257149
# differential_evolution step 316: f(x)= 1.0068491209257149
# differential_evolution step 317: f(x)= 1.0068491209257149
# differential_evolution step 318: f(x)= 1.0068491209257149
# differential_evolution step 319: f(x)= 1.0068491209257149
# differential_evolution step 320: f(x)= 1.0068491209257149
# differential_evolution step 321: f(x)= 1.0068491209257149
# differential_evolution step 322: f(x)= 1.0068491209257149
# differential_evolution step 323: f(x)= 1.0068491209257149
# differential_evolution step 324: f(x)= 1.0068491209257149
# differential_evolution step 325: f(x)= 1.0068491209257149
# differential_evolution step 326: f(x)= 1.0068491209257149
# differential_evolution step 327: f(x)= 1.0068491209257149
# differential_evolution step 328: f(x)= 1.0068491209257149
# differential_evolution step 329: f(x)= 0.9765655393442736
# differential_evolution step 330: f(x)= 0.9765655393442736
# differential_evolution step 331: f(x)= 0.9765655393442736
# differential_evolution step 332: f(x)= 0.9765655393442736
# differential_evolution step 333: f(x)= 0.9765655393442736
# differential_evolution step 334: f(x)= 0.9590927121514609
# differential_evolution step 335: f(x)= 0.9590927121514609
# differential_evolution step 336: f(x)= 0.9590927121514609
# differential_evolution step 337: f(x)= 0.9590927121514609
# differential_evolution step 338: f(x)= 0.9590927121514609
# differential_evolution step 339: f(x)= 0.8832156496649424
# differential_evolution step 340: f(x)= 0.8832156496649424
# differential_evolution step 341: f(x)= 0.8832156496649424
# differential_evolution step 342: f(x)= 0.8832156496649424
# differential_evolution step 343: f(x)= 0.8610390381403162
# differential_evolution step 344: f(x)= 0.8610390381403162
# differential_evolution step 345: f(x)= 0.8486055364655855
# differential_evolution step 346: f(x)= 0.8486055364655855
# differential_evolution step 347: f(x)= 0.8486055364655855
# differential_evolution step 348: f(x)= 0.8486055364655855
# differential_evolution step 349: f(x)= 0.8486055364655855
# differential_evolution step 350: f(x)= 0.8486055364655855
# differential_evolution step 351: f(x)= 0.8486055364655855
# differential_evolution step 352: f(x)= 0.8486055364655855
# differential_evolution step 353: f(x)= 0.8486055364655855
# differential_evolution step 354: f(x)= 0.8486055364655855
# differential_evolution step 355: f(x)= 0.8486055364655855
# differential_evolution step 356: f(x)= 0.8486055364655855
# differential_evolution step 357: f(x)= 0.8486055364655855
# differential_evolution step 358: f(x)= 0.8486055364655855
# differential_evolution step 359: f(x)= 0.8486055364655855
# differential_evolution step 360: f(x)= 0.8486055364655855
# differential_evolution step 361: f(x)= 0.8184762748337506
# differential_evolution step 362: f(x)= 0.8184762748337506
# differential_evolution step 363: f(x)= 0.8184762748337506
# differential_evolution step 364: f(x)= 0.8184762748337506
# differential_evolution step 365: f(x)= 0.8184762748337506
# differential_evolution step 366: f(x)= 0.8184762748337506
# differential_evolution step 367: f(x)= 0.8184762748337506
# differential_evolution step 368: f(x)= 0.8184762748337506
# differential_evolution step 369: f(x)= 0.7762081090010443
# differential_evolution step 370: f(x)= 0.7762081090010443
# differential_evolution step 371: f(x)= 0.7762081090010443
# differential_evolution step 372: f(x)= 0.7762081090010443
# differential_evolution step 373: f(x)= 0.7762081090010443
# differential_evolution step 374: f(x)= 0.7731318600029381
# differential_evolution step 375: f(x)= 0.7498807138035619
# differential_evolution step 376: f(x)= 0.7498807138035619
# differential_evolution step 377: f(x)= 0.7498807138035619
# differential_evolution step 378: f(x)= 0.7498807138035619
# differential_evolution step 379: f(x)= 0.7498807138035619
# differential_evolution step 380: f(x)= 0.7498807138035619
# differential_evolution step 381: f(x)= 0.7498807138035619
# differential_evolution step 382: f(x)= 0.7203847175112997
# differential_evolution step 383: f(x)= 0.7203847175112997
# differential_evolution step 384: f(x)= 0.680297495456824
# differential_evolution step 385: f(x)= 0.680297495456824
# differential_evolution step 386: f(x)= 0.680297495456824
# differential_evolution step 387: f(x)= 0.680297495456824
# differential_evolution step 388: f(x)= 0.680297495456824
# differential_evolution step 389: f(x)= 0.680297495456824
# differential_evolution step 390: f(x)= 0.680297495456824
# differential_evolution step 391: f(x)= 0.680297495456824
# differential_evolution step 392: f(x)= 0.680297495456824
# differential_evolution step 393: f(x)= 0.680297495456824
# differential_evolution step 394: f(x)= 0.680297495456824
# differential_evolution step 395: f(x)= 0.680297495456824
# differential_evolution step 396: f(x)= 0.680297495456824
# differential_evolution step 397: f(x)= 0.680297495456824
# differential_evolution step 398: f(x)= 0.680297495456824
# differential_evolution step 399: f(x)= 0.680297495456824
# differential_evolution step 400: f(x)= 0.680297495456824
# differential_evolution step 401: f(x)= 0.6676861203327253
# differential_evolution step 402: f(x)= 0.6676861203327253
# differential_evolution step 403: f(x)= 0.6676861203327253
# differential_evolution step 404: f(x)= 0.6620090007875289
# differential_evolution step 405: f(x)= 0.6620090007875289
# differential_evolution step 406: f(x)= 0.6620090007875289
# differential_evolution step 407: f(x)= 0.6620090007875289
# differential_evolution step 408: f(x)= 0.6620090007875289
# differential_evolution step 409: f(x)= 0.6620090007875289
# differential_evolution step 410: f(x)= 0.6620090007875289
# differential_evolution step 411: f(x)= 0.6565629284127424
# differential_evolution step 412: f(x)= 0.6565629284127424
# differential_evolution step 413: f(x)= 0.6565629284127424
# differential_evolution step 414: f(x)= 0.6565629284127424
# differential_evolution step 415: f(x)= 0.6565629284127424
# differential_evolution step 416: f(x)= 0.6565629284127424
# differential_evolution step 417: f(x)= 0.6565629284127424
# differential_evolution step 418: f(x)= 0.6565629284127424
# differential_evolution step 419: f(x)= 0.6565629284127424
# differential_evolution step 420: f(x)= 0.6565629284127424
# differential_evolution step 421: f(x)= 0.6565629284127424
# differential_evolution step 422: f(x)= 0.6565629284127424
# differential_evolution step 423: f(x)= 0.6565629284127424
# differential_evolution step 424: f(x)= 0.6565629284127424
# differential_evolution step 425: f(x)= 0.65628619509546
# differential_evolution step 426: f(x)= 0.65628619509546
# differential_evolution step 427: f(x)= 0.65628619509546
# differential_evolution step 428: f(x)= 0.65628619509546
# differential_evolution step 429: f(x)= 0.65628619509546
# differential_evolution step 430: f(x)= 0.65628619509546
# differential_evolution step 431: f(x)= 0.65628619509546
# differential_evolution step 432: f(x)= 0.65628619509546
# differential_evolution step 433: f(x)= 0.65628619509546
# differential_evolution step 434: f(x)= 0.65628619509546
# differential_evolution step 435: f(x)= 0.65628619509546
# differential_evolution step 436: f(x)= 0.65628619509546
# differential_evolution step 437: f(x)= 0.65628619509546
# differential_evolution step 438: f(x)= 0.65628619509546
# differential_evolution step 439: f(x)= 0.65628619509546
# differential_evolution step 440: f(x)= 0.6488348582012744
# differential_evolution step 441: f(x)= 0.6488348582012744
# differential_evolution step 442: f(x)= 0.6200382284723087
# differential_evolution step 443: f(x)= 0.6200382284723087
# differential_evolution step 444: f(x)= 0.6200382284723087
# differential_evolution step 445: f(x)= 0.6200382284723087
# differential_evolution step 446: f(x)= 0.6200382284723087
# differential_evolution step 447: f(x)= 0.6200382284723087
# differential_evolution step 448: f(x)= 0.6200382284723087
# differential_evolution step 449: f(x)= 0.6200382284723087
# differential_evolution step 450: f(x)= 0.6200382284723087
# differential_evolution step 451: f(x)= 0.6200382284723087
# differential_evolution step 452: f(x)= 0.6200382284723087
# differential_evolution step 453: f(x)= 0.6200382284723087
# differential_evolution step 454: f(x)= 0.6200382284723087
# differential_evolution step 455: f(x)= 0.5698875609831414
# differential_evolution step 456: f(x)= 0.5698875609831414
# differential_evolution step 457: f(x)= 0.5698875609831414
# differential_evolution step 458: f(x)= 0.5698875609831414
# differential_evolution step 459: f(x)= 0.5698875609831414
# differential_evolution step 460: f(x)= 0.5698875609831414
# differential_evolution step 461: f(x)= 0.5698875609831414
# differential_evolution step 462: f(x)= 0.5698875609831414
# differential_evolution step 463: f(x)= 0.5698875609831414
# differential_evolution step 464: f(x)= 0.5698875609831414
# differential_evolution step 465: f(x)= 0.5698875609831414
# differential_evolution step 466: f(x)= 0.5698875609831414
# differential_evolution step 467: f(x)= 0.5698875609831414
# differential_evolution step 468: f(x)= 0.5698875609831414
# differential_evolution step 469: f(x)= 0.5698875609831414
# differential_evolution step 470: f(x)= 0.5698875609831414
# differential_evolution step 471: f(x)= 0.5698875609831414
# differential_evolution step 472: f(x)= 0.538634231735344
# differential_evolution step 473: f(x)= 0.538634231735344
# differential_evolution step 474: f(x)= 0.538634231735344
# differential_evolution step 475: f(x)= 0.538634231735344
# differential_evolution step 476: f(x)= 0.538634231735344
# differential_evolution step 477: f(x)= 0.538634231735344
# differential_evolution step 478: f(x)= 0.538634231735344
# differential_evolution step 479: f(x)= 0.538634231735344
# differential_evolution step 480: f(x)= 0.538634231735344
# differential_evolution step 481: f(x)= 0.538634231735344
# differential_evolution step 482: f(x)= 0.538634231735344
# differential_evolution step 483: f(x)= 0.538634231735344
# differential_evolution step 484: f(x)= 0.538634231735344
# differential_evolution step 485: f(x)= 0.538634231735344
# differential_evolution step 486: f(x)= 0.538634231735344
# differential_evolution step 487: f(x)= 0.538634231735344
# differential_evolution step 488: f(x)= 0.538634231735344
# differential_evolution step 489: f(x)= 0.538634231735344
# differential_evolution step 490: f(x)= 0.538634231735344
# differential_evolution step 491: f(x)= 0.538634231735344
# differential_evolution step 492: f(x)= 0.538634231735344
# differential_evolution step 493: f(x)= 0.538634231735344
# differential_evolution step 494: f(x)= 0.538634231735344
# differential_evolution step 495: f(x)= 0.538634231735344
# differential_evolution step 496: f(x)= 0.538634231735344
# differential_evolution step 497: f(x)= 0.538634231735344
# differential_evolution step 498: f(x)= 0.538634231735344
# differential_evolution step 499: f(x)= 0.538634231735344
# differential_evolution step 500: f(x)= 0.538634231735344
# differential_evolution step 501: f(x)= 0.538634231735344
# differential_evolution step 502: f(x)= 0.538634231735344
# differential_evolution step 503: f(x)= 0.538634231735344
# differential_evolution step 504: f(x)= 0.538634231735344
# differential_evolution step 505: f(x)= 0.538634231735344
# differential_evolution step 506: f(x)= 0.538634231735344
# differential_evolution step 507: f(x)= 0.538634231735344
# differential_evolution step 508: f(x)= 0.538634231735344
# differential_evolution step 509: f(x)= 0.538634231735344
# differential_evolution step 510: f(x)= 0.538634231735344
# differential_evolution step 511: f(x)= 0.538634231735344
# differential_evolution step 512: f(x)= 0.538634231735344
# differential_evolution step 513: f(x)= 0.538634231735344
# differential_evolution step 514: f(x)= 0.538634231735344
# differential_evolution step 515: f(x)= 0.538634231735344
# differential_evolution step 516: f(x)= 0.538634231735344
# differential_evolution step 517: f(x)= 0.520284707744561
# differential_evolution step 518: f(x)= 0.520284707744561
# differential_evolution step 519: f(x)= 0.520284707744561
# differential_evolution step 520: f(x)= 0.520284707744561
# differential_evolution step 521: f(x)= 0.520284707744561
# differential_evolution step 522: f(x)= 0.520284707744561
# differential_evolution step 523: f(x)= 0.520284707744561
# differential_evolution step 524: f(x)= 0.520284707744561
# differential_evolution step 525: f(x)= 0.520284707744561
# differential_evolution step 526: f(x)= 0.520284707744561
# differential_evolution step 527: f(x)= 0.520284707744561
# differential_evolution step 528: f(x)= 0.520284707744561
# differential_evolution step 529: f(x)= 0.520284707744561
# differential_evolution step 530: f(x)= 0.520284707744561
# differential_evolution step 531: f(x)= 0.520284707744561
# differential_evolution step 532: f(x)= 0.520284707744561
# differential_evolution step 533: f(x)= 0.520284707744561
# differential_evolution step 534: f(x)= 0.520284707744561
# differential_evolution step 535: f(x)= 0.520284707744561
# differential_evolution step 536: f(x)= 0.520284707744561
# differential_evolution step 537: f(x)= 0.520284707744561
# differential_evolution step 538: f(x)= 0.520284707744561
# differential_evolution step 539: f(x)= 0.520284707744561
# differential_evolution step 540: f(x)= 0.520284707744561
# differential_evolution step 541: f(x)= 0.520284707744561
# differential_evolution step 542: f(x)= 0.520284707744561
# differential_evolution step 543: f(x)= 0.520284707744561
# differential_evolution step 544: f(x)= 0.520284707744561
# differential_evolution step 545: f(x)= 0.520284707744561
# differential_evolution step 546: f(x)= 0.520284707744561
# differential_evolution step 547: f(x)= 0.520284707744561
# differential_evolution step 548: f(x)= 0.520284707744561
# differential_evolution step 549: f(x)= 0.4931753337663319
# differential_evolution step 550: f(x)= 0.4931753337663319
# differential_evolution step 551: f(x)= 0.4931753337663319
# differential_evolution step 552: f(x)= 0.4931753337663319
# differential_evolution step 553: f(x)= 0.4931753337663319
# differential_evolution step 554: f(x)= 0.4931753337663319
# differential_evolution step 555: f(x)= 0.4931753337663319
# differential_evolution step 556: f(x)= 0.4931753337663319
# differential_evolution step 557: f(x)= 0.4931753337663319
# differential_evolution step 558: f(x)= 0.4931753337663319
# differential_evolution step 559: f(x)= 0.4931753337663319
# differential_evolution step 560: f(x)= 0.4931753337663319
# differential_evolution step 561: f(x)= 0.4931753337663319
# differential_evolution step 562: f(x)= 0.4931753337663319
# differential_evolution step 563: f(x)= 0.4931753337663319
# differential_evolution step 564: f(x)= 0.4931753337663319
# differential_evolution step 565: f(x)= 0.4931753337663319
# differential_evolution step 566: f(x)= 0.4931753337663319
# differential_evolution step 567: f(x)= 0.4931753337663319
# differential_evolution step 568: f(x)= 0.4931753337663319
# differential_evolution step 569: f(x)= 0.4931753337663319
# differential_evolution step 570: f(x)= 0.4931753337663319
# differential_evolution step 571: f(x)= 0.4931753337663319
# differential_evolution step 572: f(x)= 0.4931753337663319
# differential_evolution step 573: f(x)= 0.4931753337663319
# differential_evolution step 574: f(x)= 0.4931753337663319
# differential_evolution step 575: f(x)= 0.4931753337663319
# differential_evolution step 576: f(x)= 0.4931753337663319
# differential_evolution step 577: f(x)= 0.4931753337663319
# differential_evolution step 578: f(x)= 0.4931753337663319
# differential_evolution step 579: f(x)= 0.4931753337663319
# differential_evolution step 580: f(x)= 0.4931753337663319
# differential_evolution step 581: f(x)= 0.4931753337663319
# differential_evolution step 582: f(x)= 0.4931753337663319
# differential_evolution step 583: f(x)= 0.4931753337663319
# differential_evolution step 584: f(x)= 0.4931753337663319
# differential_evolution step 585: f(x)= 0.4931753337663319
# differential_evolution step 586: f(x)= 0.4931753337663319
# differential_evolution step 587: f(x)= 0.4931753337663319
# differential_evolution step 588: f(x)= 0.4931753337663319
# differential_evolution step 589: f(x)= 0.4931753337663319
# differential_evolution step 590: f(x)= 0.4907019853458034
# differential_evolution step 591: f(x)= 0.4907019853458034
# differential_evolution step 592: f(x)= 0.4907019853458034
# differential_evolution step 593: f(x)= 0.4907019853458034
# differential_evolution step 594: f(x)= 0.485684826306812
# differential_evolution step 595: f(x)= 0.485684826306812
# differential_evolution step 596: f(x)= 0.47347578837361876
# differential_evolution step 597: f(x)= 0.47347578837361876
# differential_evolution step 598: f(x)= 0.47347578837361876
# differential_evolution step 599: f(x)= 0.47347578837361876
# differential_evolution step 600: f(x)= 0.47347578837361876
# differential_evolution step 601: f(x)= 0.47347578837361876
# differential_evolution step 602: f(x)= 0.47347578837361876
# differential_evolution step 603: f(x)= 0.47347578837361876
# differential_evolution step 604: f(x)= 0.47347578837361876
# differential_evolution step 605: f(x)= 0.47347578837361876
# differential_evolution step 606: f(x)= 0.47347578837361876
# differential_evolution step 607: f(x)= 0.47347578837361876
# differential_evolution step 608: f(x)= 0.47347578837361876
# differential_evolution step 609: f(x)= 0.4462700256202204
# differential_evolution step 610: f(x)= 0.4462700256202204
# differential_evolution step 611: f(x)= 0.4462700256202204
# differential_evolution step 612: f(x)= 0.4462700256202204
# differential_evolution step 613: f(x)= 0.4462700256202204
# differential_evolution step 614: f(x)= 0.4462700256202204
# differential_evolution step 615: f(x)= 0.4462700256202204
# differential_evolution step 616: f(x)= 0.4462700256202204
# differential_evolution step 617: f(x)= 0.4462700256202204
# differential_evolution step 618: f(x)= 0.4462700256202204
# differential_evolution step 619: f(x)= 0.4462700256202204
# differential_evolution step 620: f(x)= 0.4462700256202204
# differential_evolution step 621: f(x)= 0.4462700256202204
# differential_evolution step 622: f(x)= 0.4462700256202204
# differential_evolution step 623: f(x)= 0.4462700256202204
# differential_evolution step 624: f(x)= 0.4462700256202204
# differential_evolution step 625: f(x)= 0.4462700256202204
# differential_evolution step 626: f(x)= 0.4462700256202204
# differential_evolution step 627: f(x)= 0.4462700256202204
# differential_evolution step 628: f(x)= 0.4462700256202204
# differential_evolution step 629: f(x)= 0.4462700256202204
# differential_evolution step 630: f(x)= 0.4462700256202204
# differential_evolution step 631: f(x)= 0.4462700256202204
# differential_evolution step 632: f(x)= 0.4462700256202204
# differential_evolution step 633: f(x)= 0.4462700256202204
# differential_evolution step 634: f(x)= 0.4462700256202204
# differential_evolution step 635: f(x)= 0.4462700256202204
# differential_evolution step 636: f(x)= 0.4462700256202204
# differential_evolution step 637: f(x)= 0.4462700256202204
# differential_evolution step 638: f(x)= 0.4462700256202204
# differential_evolution step 639: f(x)= 0.4462700256202204
# differential_evolution step 640: f(x)= 0.4462700256202204
# differential_evolution step 641: f(x)= 0.4462700256202204
# differential_evolution step 642: f(x)= 0.4462700256202204
# differential_evolution step 643: f(x)= 0.4462700256202204
# differential_evolution step 644: f(x)= 0.4462700256202204
# differential_evolution step 645: f(x)= 0.4462700256202204
# differential_evolution step 646: f(x)= 0.4462700256202204
# differential_evolution step 647: f(x)= 0.4462700256202204
# differential_evolution step 648: f(x)= 0.4462700256202204
# differential_evolution step 649: f(x)= 0.4462700256202204
# differential_evolution step 650: f(x)= 0.4462700256202204
# differential_evolution step 651: f(x)= 0.4462700256202204
# differential_evolution step 652: f(x)= 0.4462700256202204
# differential_evolution step 653: f(x)= 0.4462700256202204
# differential_evolution step 654: f(x)= 0.4462700256202204
# differential_evolution step 655: f(x)= 0.4462700256202204
# differential_evolution step 656: f(x)= 0.4462700256202204
# differential_evolution step 657: f(x)= 0.4462700256202204
# differential_evolution step 658: f(x)= 0.4462700256202204
# differential_evolution step 659: f(x)= 0.4462700256202204
# differential_evolution step 660: f(x)= 0.4462700256202204
# differential_evolution step 661: f(x)= 0.4462700256202204
# differential_evolution step 662: f(x)= 0.4462700256202204
# differential_evolution step 663: f(x)= 0.4462700256202204
# differential_evolution step 664: f(x)= 0.4462700256202204
# differential_evolution step 665: f(x)= 0.4462700256202204
# differential_evolution step 666: f(x)= 0.4399832943179691
# differential_evolution step 667: f(x)= 0.4399832943179691
# differential_evolution step 668: f(x)= 0.4399832943179691
# differential_evolution step 669: f(x)= 0.4399832943179691
# differential_evolution step 670: f(x)= 0.4399832943179691
# differential_evolution step 671: f(x)= 0.4399832943179691
# differential_evolution step 672: f(x)= 0.4399832943179691
# differential_evolution step 673: f(x)= 0.4399832943179691
# differential_evolution step 674: f(x)= 0.4399832943179691
# differential_evolution step 675: f(x)= 0.4399832943179691
# differential_evolution step 676: f(x)= 0.4399832943179691
# differential_evolution step 677: f(x)= 0.4314885380749692
# differential_evolution step 678: f(x)= 0.4262558991960124
# differential_evolution step 679: f(x)= 0.4262558991960124
# differential_evolution step 680: f(x)= 0.4262558991960124
# differential_evolution step 681: f(x)= 0.4262558991960124
# differential_evolution step 682: f(x)= 0.4262558991960124
# differential_evolution step 683: f(x)= 0.4262558991960124
# differential_evolution step 684: f(x)= 0.4071366873549871
# differential_evolution step 685: f(x)= 0.4071366873549871
# differential_evolution step 686: f(x)= 0.4071366873549871
# differential_evolution step 687: f(x)= 0.4071366873549871
# differential_evolution step 688: f(x)= 0.4071366873549871
# differential_evolution step 689: f(x)= 0.4071366873549871
# differential_evolution step 690: f(x)= 0.4071366873549871
# differential_evolution step 691: f(x)= 0.4071366873549871
# differential_evolution step 692: f(x)= 0.4071366873549871
# differential_evolution step 693: f(x)= 0.4071366873549871
# differential_evolution step 694: f(x)= 0.4071366873549871
# differential_evolution step 695: f(x)= 0.4071366873549871
# differential_evolution step 696: f(x)= 0.4071366873549871
# differential_evolution step 697: f(x)= 0.4071366873549871
# differential_evolution step 698: f(x)= 0.39539517731817087
# differential_evolution step 699: f(x)= 0.39539517731817087
# differential_evolution step 700: f(x)= 0.39539517731817087
# differential_evolution step 701: f(x)= 0.39539517731817087
# differential_evolution step 702: f(x)= 0.39539517731817087
# differential_evolution step 703: f(x)= 0.39539517731817087
# differential_evolution step 704: f(x)= 0.39539517731817087
# differential_evolution step 705: f(x)= 0.39539517731817087
# differential_evolution step 706: f(x)= 0.39539517731817087
# differential_evolution step 707: f(x)= 0.39539517731817087
# differential_evolution step 708: f(x)= 0.39539517731817087
# differential_evolution step 709: f(x)= 0.39539517731817087
# differential_evolution step 710: f(x)= 0.39539517731817087
# differential_evolution step 711: f(x)= 0.39539517731817087
# differential_evolution step 712: f(x)= 0.39539517731817087
# differential_evolution step 713: f(x)= 0.39539517731817087
# differential_evolution step 714: f(x)= 0.39539517731817087
# differential_evolution step 715: f(x)= 0.39539517731817087
# differential_evolution step 716: f(x)= 0.39539517731817087
# differential_evolution step 717: f(x)= 0.3910606281739087
# differential_evolution step 718: f(x)= 0.3910606281739087
# differential_evolution step 719: f(x)= 0.3910606281739087
# differential_evolution step 720: f(x)= 0.3910606281739087
# differential_evolution step 721: f(x)= 0.3910606281739087
# differential_evolution step 722: f(x)= 0.3910606281739087
# differential_evolution step 723: f(x)= 0.3910606281739087
# differential_evolution step 724: f(x)= 0.3910606281739087
# differential_evolution step 725: f(x)= 0.3910606281739087
# differential_evolution step 726: f(x)= 0.3910606281739087
# differential_evolution step 727: f(x)= 0.3910606281739087
# differential_evolution step 728: f(x)= 0.3910606281739087
# differential_evolution step 729: f(x)= 0.3910606281739087
# differential_evolution step 730: f(x)= 0.3910606281739087
# differential_evolution step 731: f(x)= 0.3910606281739087
# differential_evolution step 732: f(x)= 0.3910606281739087
# differential_evolution step 733: f(x)= 0.3910606281739087
# differential_evolution step 734: f(x)= 0.3910606281739087
# differential_evolution step 735: f(x)= 0.3910606281739087
# differential_evolution step 736: f(x)= 0.3910606281739087
# differential_evolution step 737: f(x)= 0.3910606281739087
# differential_evolution step 738: f(x)= 0.3910606281739087
# differential_evolution step 739: f(x)= 0.3910606281739087
# differential_evolution step 740: f(x)= 0.3910606281739087
# differential_evolution step 741: f(x)= 0.3910606281739087
# differential_evolution step 742: f(x)= 0.3910606281739087
# differential_evolution step 743: f(x)= 0.3910606281739087
# differential_evolution step 744: f(x)= 0.3910606281739087
# differential_evolution step 745: f(x)= 0.3910606281739087
# differential_evolution step 746: f(x)= 0.3910606281739087
# differential_evolution step 747: f(x)= 0.3910606281739087
# differential_evolution step 748: f(x)= 0.3910606281739087
# differential_evolution step 749: f(x)= 0.3910606281739087
# differential_evolution step 750: f(x)= 0.3910606281739087
# differential_evolution step 751: f(x)= 0.3910606281739087
# differential_evolution step 752: f(x)= 0.3910606281739087
# differential_evolution step 753: f(x)= 0.3910606281739087
# differential_evolution step 754: f(x)= 0.3910606281739087
# differential_evolution step 755: f(x)= 0.3910606281739087
# differential_evolution step 756: f(x)= 0.38654267445902046
# differential_evolution step 757: f(x)= 0.38654267445902046
# differential_evolution step 758: f(x)= 0.38654267445902046
# differential_evolution step 759: f(x)= 0.38654267445902046
# differential_evolution step 760: f(x)= 0.38654267445902046
# differential_evolution step 761: f(x)= 0.38654267445902046
# differential_evolution step 762: f(x)= 0.38654267445902046
# differential_evolution step 763: f(x)= 0.38654267445902046
# differential_evolution step 764: f(x)= 0.38654267445902046
# differential_evolution step 765: f(x)= 0.38654267445902046
# differential_evolution step 766: f(x)= 0.38654267445902046
# differential_evolution step 767: f(x)= 0.38654267445902046
# differential_evolution step 768: f(x)= 0.38654267445902046
# differential_evolution step 769: f(x)= 0.38654267445902046
# differential_evolution step 770: f(x)= 0.38654267445902046
# differential_evolution step 771: f(x)= 0.38654267445902046
# differential_evolution step 772: f(x)= 0.3767540885765563
# differential_evolution step 773: f(x)= 0.3767540885765563
# differential_evolution step 774: f(x)= 0.3767540885765563
# differential_evolution step 775: f(x)= 0.3767540885765563
# differential_evolution step 776: f(x)= 0.3767540885765563
# differential_evolution step 777: f(x)= 0.3767540885765563
# differential_evolution step 778: f(x)= 0.3767540885765563
# differential_evolution step 779: f(x)= 0.3767540885765563
# differential_evolution step 780: f(x)= 0.3767540885765563
# differential_evolution step 781: f(x)= 0.3767540885765563
# differential_evolution step 782: f(x)= 0.3767540885765563
# differential_evolution step 783: f(x)= 0.3767540885765563
# differential_evolution step 784: f(x)= 0.3767540885765563
# differential_evolution step 785: f(x)= 0.3767540885765563
# differential_evolution step 786: f(x)= 0.3767540885765563
# differential_evolution step 787: f(x)= 0.3767540885765563
# differential_evolution step 788: f(x)= 0.3767540885765563
# differential_evolution step 789: f(x)= 0.3767540885765563
# differential_evolution step 790: f(x)= 0.3767540885765563
# differential_evolution step 791: f(x)= 0.3767540885765563
# differential_evolution step 792: f(x)= 0.3767540885765563
# differential_evolution step 793: f(x)= 0.3767540885765563
# differential_evolution step 794: f(x)= 0.3767540885765563
# differential_evolution step 795: f(x)= 0.3767540885765563
# differential_evolution step 796: f(x)= 0.37516743584873574
# differential_evolution step 797: f(x)= 0.37516743584873574
# differential_evolution step 798: f(x)= 0.37516743584873574
# differential_evolution step 799: f(x)= 0.37516743584873574
# differential_evolution step 800: f(x)= 0.37516743584873574
# differential_evolution step 801: f(x)= 0.37516743584873574
# differential_evolution step 802: f(x)= 0.37516743584873574
# differential_evolution step 803: f(x)= 0.3717361992828068
# differential_evolution step 804: f(x)= 0.36865441711440294
# differential_evolution step 805: f(x)= 0.36865441711440294
# differential_evolution step 806: f(x)= 0.36865441711440294
# differential_evolution step 807: f(x)= 0.36865441711440294
# differential_evolution step 808: f(x)= 0.36865441711440294
# differential_evolution step 809: f(x)= 0.36865441711440294
# differential_evolution step 810: f(x)= 0.36865441711440294
# differential_evolution step 811: f(x)= 0.36865441711440294
# differential_evolution step 812: f(x)= 0.36865441711440294
# differential_evolution step 813: f(x)= 0.36865441711440294
# differential_evolution step 814: f(x)= 0.36865441711440294
# differential_evolution step 815: f(x)= 0.36865441711440294
# differential_evolution step 816: f(x)= 0.36865441711440294
# differential_evolution step 817: f(x)= 0.36865441711440294
# differential_evolution step 818: f(x)= 0.36865441711440294
# differential_evolution step 819: f(x)= 0.36865441711440294
# differential_evolution step 820: f(x)= 0.36865441711440294
# differential_evolution step 821: f(x)= 0.36865441711440294
# differential_evolution step 822: f(x)= 0.36865441711440294
# differential_evolution step 823: f(x)= 0.36865441711440294
# differential_evolution step 824: f(x)= 0.36865441711440294
# differential_evolution step 825: f(x)= 0.36865441711440294
# differential_evolution step 826: f(x)= 0.36865441711440294
# differential_evolution step 827: f(x)= 0.36865441711440294
# differential_evolution step 828: f(x)= 0.3662554669836508
# differential_evolution step 829: f(x)= 0.3662554669836508
# differential_evolution step 830: f(x)= 0.3662554669836508
# differential_evolution step 831: f(x)= 0.3662554669836508
# differential_evolution step 832: f(x)= 0.3662554669836508
# differential_evolution step 833: f(x)= 0.3662554669836508
# differential_evolution step 834: f(x)= 0.3662554669836508
# differential_evolution step 835: f(x)= 0.3662554669836508
# differential_evolution step 836: f(x)= 0.36584722541122167
# differential_evolution step 837: f(x)= 0.36584722541122167
# differential_evolution step 838: f(x)= 0.36584722541122167
# differential_evolution step 839: f(x)= 0.36584722541122167
# differential_evolution step 840: f(x)= 0.36584722541122167
# differential_evolution step 841: f(x)= 0.36584722541122167
# differential_evolution step 842: f(x)= 0.36584722541122167
# differential_evolution step 843: f(x)= 0.36584722541122167
# differential_evolution step 844: f(x)= 0.36584722541122167
# differential_evolution step 845: f(x)= 0.3475758040073633
# differential_evolution step 846: f(x)= 0.3475758040073633
# differential_evolution step 847: f(x)= 0.3475758040073633
# differential_evolution step 848: f(x)= 0.3475758040073633
# differential_evolution step 849: f(x)= 0.3475758040073633
# differential_evolution step 850: f(x)= 0.3475758040073633
# differential_evolution step 851: f(x)= 0.3475758040073633
# differential_evolution step 852: f(x)= 0.3475758040073633
# differential_evolution step 853: f(x)= 0.3475758040073633
# differential_evolution step 854: f(x)= 0.3475758040073633
# differential_evolution step 855: f(x)= 0.3475758040073633
# differential_evolution step 856: f(x)= 0.3475758040073633
# differential_evolution step 857: f(x)= 0.3475758040073633
# differential_evolution step 858: f(x)= 0.3475758040073633
# differential_evolution step 859: f(x)= 0.3475758040073633
# differential_evolution step 860: f(x)= 0.3475758040073633
# differential_evolution step 861: f(x)= 0.3475758040073633
# differential_evolution step 862: f(x)= 0.3475758040073633
# differential_evolution step 863: f(x)= 0.3475758040073633
# differential_evolution step 864: f(x)= 0.3475758040073633
# differential_evolution step 865: f(x)= 0.3475758040073633
# differential_evolution step 866: f(x)= 0.3475758040073633
# differential_evolution step 867: f(x)= 0.3350086685306252
# differential_evolution step 868: f(x)= 0.3350086685306252
# differential_evolution step 869: f(x)= 0.3350086685306252
# differential_evolution step 870: f(x)= 0.3350086685306252
# differential_evolution step 871: f(x)= 0.3350086685306252
# differential_evolution step 872: f(x)= 0.3350086685306252
# differential_evolution step 873: f(x)= 0.3350086685306252
# differential_evolution step 874: f(x)= 0.3350086685306252
# differential_evolution step 875: f(x)= 0.3350086685306252
# differential_evolution step 876: f(x)= 0.3350086685306252
# differential_evolution step 877: f(x)= 0.3350086685306252
# differential_evolution step 878: f(x)= 0.3350086685306252
# differential_evolution step 879: f(x)= 0.3350086685306252
# differential_evolution step 880: f(x)= 0.3350086685306252
# differential_evolution step 881: f(x)= 0.3350086685306252
# differential_evolution step 882: f(x)= 0.3350086685306252
# differential_evolution step 883: f(x)= 0.3350086685306252
# differential_evolution step 884: f(x)= 0.3350086685306252
# differential_evolution step 885: f(x)= 0.3350086685306252
# differential_evolution step 886: f(x)= 0.3350086685306252
# differential_evolution step 887: f(x)= 0.3350086685306252
# differential_evolution step 888: f(x)= 0.3350086685306252
# differential_evolution step 889: f(x)= 0.3350086685306252
# differential_evolution step 890: f(x)= 0.3350086685306252
# differential_evolution step 891: f(x)= 0.3350086685306252
# differential_evolution step 892: f(x)= 0.3350086685306252
# differential_evolution step 893: f(x)= 0.3350086685306252
# differential_evolution step 894: f(x)= 0.3350086685306252
# differential_evolution step 895: f(x)= 0.3350086685306252
# differential_evolution step 896: f(x)= 0.3350086685306252
# differential_evolution step 897: f(x)= 0.3350086685306252
# differential_evolution step 898: f(x)= 0.3350086685306252
# differential_evolution step 899: f(x)= 0.3350086685306252
# differential_evolution step 900: f(x)= 0.3309960532534451
# differential_evolution step 901: f(x)= 0.3309960532534451
# differential_evolution step 902: f(x)= 0.3309960532534451
# differential_evolution step 903: f(x)= 0.3309960532534451
# differential_evolution step 904: f(x)= 0.3309960532534451
# differential_evolution step 905: f(x)= 0.3309960532534451
# differential_evolution step 906: f(x)= 0.3309960532534451
# differential_evolution step 907: f(x)= 0.3233983338938207
# differential_evolution step 908: f(x)= 0.3233983338938207
# differential_evolution step 909: f(x)= 0.3233983338938207
# differential_evolution step 910: f(x)= 0.3233983338938207
# differential_evolution step 911: f(x)= 0.3233983338938207
# differential_evolution step 912: f(x)= 0.3233983338938207
# differential_evolution step 913: f(x)= 0.3233983338938207
# differential_evolution step 914: f(x)= 0.3233983338938207
# differential_evolution step 915: f(x)= 0.3233983338938207
# differential_evolution step 916: f(x)= 0.3233983338938207
# differential_evolution step 917: f(x)= 0.3233983338938207
# differential_evolution step 918: f(x)= 0.3233983338938207
# differential_evolution step 919: f(x)= 0.3233983338938207
# differential_evolution step 920: f(x)= 0.3233983338938207
# differential_evolution step 921: f(x)= 0.3233983338938207
# differential_evolution step 922: f(x)= 0.3233983338938207
# differential_evolution step 923: f(x)= 0.3233983338938207
# differential_evolution step 924: f(x)= 0.3233983338938207
# differential_evolution step 925: f(x)= 0.3233983338938207
# differential_evolution step 926: f(x)= 0.3233983338938207
# differential_evolution step 927: f(x)= 0.3233983338938207
# differential_evolution step 928: f(x)= 0.3233983338938207
# differential_evolution step 929: f(x)= 0.3233983338938207
# differential_evolution step 930: f(x)= 0.3233983338938207
# differential_evolution step 931: f(x)= 0.3233983338938207
# differential_evolution step 932: f(x)= 0.3233983338938207
# differential_evolution step 933: f(x)= 0.3233983338938207
# differential_evolution step 934: f(x)= 0.3233983338938207
# differential_evolution step 935: f(x)= 0.3233983338938207
# differential_evolution step 936: f(x)= 0.3233983338938207
# differential_evolution step 937: f(x)= 0.3233983338938207
# differential_evolution step 938: f(x)= 0.3233983338938207
# differential_evolution step 939: f(x)= 0.3233983338938207
# differential_evolution step 940: f(x)= 0.3233983338938207
# differential_evolution step 941: f(x)= 0.3233983338938207
# differential_evolution step 942: f(x)= 0.3233983338938207
# differential_evolution step 943: f(x)= 0.3233983338938207
# differential_evolution step 944: f(x)= 0.3233983338938207
# differential_evolution step 945: f(x)= 0.3233983338938207
# differential_evolution step 946: f(x)= 0.3233983338938207
# differential_evolution step 947: f(x)= 0.3233983338938207
# differential_evolution step 948: f(x)= 0.3233983338938207
# differential_evolution step 949: f(x)= 0.3233983338938207
# differential_evolution step 950: f(x)= 0.3233983338938207
# differential_evolution step 951: f(x)= 0.3233983338938207
# differential_evolution step 952: f(x)= 0.3233983338938207
# differential_evolution step 953: f(x)= 0.3233983338938207
# differential_evolution step 954: f(x)= 0.3233983338938207
# differential_evolution step 955: f(x)= 0.3233983338938207
# differential_evolution step 956: f(x)= 0.3233983338938207
# differential_evolution step 957: f(x)= 0.3233983338938207
# differential_evolution step 958: f(x)= 0.3233983338938207
# differential_evolution step 959: f(x)= 0.3233983338938207
# differential_evolution step 960: f(x)= 0.3233983338938207
# differential_evolution step 961: f(x)= 0.3233983338938207
# differential_evolution step 962: f(x)= 0.3233983338938207
# differential_evolution step 963: f(x)= 0.3233983338938207
# differential_evolution step 964: f(x)= 0.3233983338938207
# differential_evolution step 965: f(x)= 0.3233983338938207
# differential_evolution step 966: f(x)= 0.3233983338938207
# differential_evolution step 967: f(x)= 0.3233983338938207
# differential_evolution step 968: f(x)= 0.3233983338938207
# differential_evolution step 969: f(x)= 0.3233983338938207
# differential_evolution step 970: f(x)= 0.3233983338938207
# differential_evolution step 971: f(x)= 0.3233983338938207
# differential_evolution step 972: f(x)= 0.3233983338938207
# differential_evolution step 973: f(x)= 0.3233983338938207
# differential_evolution step 974: f(x)= 0.3233983338938207
# differential_evolution step 975: f(x)= 0.3233983338938207
# differential_evolution step 976: f(x)= 0.3233983338938207
# differential_evolution step 977: f(x)= 0.3233983338938207
# differential_evolution step 978: f(x)= 0.3233983338938207
# differential_evolution step 979: f(x)= 0.3233983338938207
# differential_evolution step 980: f(x)= 0.3233983338938207
# differential_evolution step 981: f(x)= 0.3233983338938207
# differential_evolution step 982: f(x)= 0.3233983338938207
# differential_evolution step 983: f(x)= 0.3233983338938207
# differential_evolution step 984: f(x)= 0.3233983338938207
# differential_evolution step 985: f(x)= 0.3233983338938207
# differential_evolution step 986: f(x)= 0.3233983338938207
# differential_evolution step 987: f(x)= 0.3233983338938207
# differential_evolution step 988: f(x)= 0.3233983338938207
# differential_evolution step 989: f(x)= 0.3233983338938207
# differential_evolution step 990: f(x)= 0.3233983338938207
# differential_evolution step 991: f(x)= 0.3233983338938207
# differential_evolution step 992: f(x)= 0.3233983338938207
# differential_evolution step 993: f(x)= 0.3233983338938207
# differential_evolution step 994: f(x)= 0.3233983338938207
# differential_evolution step 995: f(x)= 0.3233983338938207
# differential_evolution step 996: f(x)= 0.3233983338938207
# differential_evolution step 997: f(x)= 0.3233983338938207
# differential_evolution step 998: f(x)= 0.3233983338938207
# differential_evolution step 999: f(x)= 0.3233983338938207
# differential_evolution step 1000: f(x)= 0.3233983338938207
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [6.91716495e-01 2.43004831e+00 2.07586692e+00 2.88162040e+01
#  2.74302278e-01 3.48065825e+00 1.53221185e+00 5.69804242e+01
#  2.26410554e-01 3.80494952e+00 1.47360658e+00 7.74000392e+01
#  3.02181648e-01 2.58914341e+00 1.43662891e+00 8.29259599e+01
#  1.50584983e-01 6.08193216e+00 1.20073637e+00 1.43999975e+01
#  4.96854745e-02 4.71008614e+01 1.41631887e+00 7.17529284e+01]
# Chi quadro minimo: 0.2784786759376561

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\2414547421.py:12: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.5020, r_e=3.0457, n=2.3079, x_0=28.8157
# Sérsic 2: I_e=0.1599, r_e=5.7835, n=1.8549, x_0=57.0382
# Sérsic 3: I_e=0.2429, r_e=2.9773, n=1.6027, x_0=77.3692
# Sérsic 4: I_e=0.7274, r_e=1.9404, n=0.6977, x_0=82.9248
# Sérsic 5: I_e=0.1431, r_e=6.1382, n=1.2380, x_0=14.3837
# Sérsic 6: I_e=0.0163, r_e=86.3786, n=2.2389, x_0=72.3364
# [1.82010522e-01 5.92389004e-01 4.29229492e-01 2.87915686e-02
#  7.82872527e-02 1.97748987e+00 4.65422050e-01 7.13828013e-02
#  1.11209662e+00 9.98570965e+00 3.45587389e+00 1.37235066e-01
#  2.69028514e-01 5.27477075e-01 3.51007796e-01 1.71582728e-01
#  4.87710372e-02 1.44778660e+00 2.56558882e-01 1.25985708e-01
#  1.95163509e-02 8.17581098e+01 6.60444906e-01 5.70024943e-01]
# 21.047509435562574
# 85.04750943556257 21.047509435562574 131.57159389927676 24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24]) +
        sersic_1d(x_hr, *params[24:28])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (75, 79),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (80, 85),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 16),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 70),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params7 = result.x

print("Optimize parameters with differential_evolution:", best_params7)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 152444.4409366518
# differential_evolution step 2: f(x)= 126181.91111075206
# differential_evolution step 3: f(x)= 34938.11432951084
# differential_evolution step 4: f(x)= 34938.11432951084
# differential_evolution step 5: f(x)= 34938.11432951084
# differential_evolution step 6: f(x)= 34938.11432951084
# differential_evolution step 7: f(x)= 34938.11432951084
# differential_evolution step 8: f(x)= 15360.084448629194
# differential_evolution step 9: f(x)= 15360.084448629194
# differential_evolution step 10: f(x)= 15360.084448629194
# differential_evolution step 11: f(x)= 15360.084448629194
# differential_evolution step 12: f(x)= 15360.084448629194
# differential_evolution step 13: f(x)= 15360.084448629194
# differential_evolution step 14: f(x)= 15360.084448629194
# differential_evolution step 15: f(x)= 15360.084448629194
# differential_evolution step 16: f(x)= 15360.084448629194
# differential_evolution step 17: f(x)= 15360.084448629194
# differential_evolution step 18: f(x)= 9544.928277820545
# differential_evolution step 19: f(x)= 9544.928277820545
# differential_evolution step 20: f(x)= 9544.928277820545
# differential_evolution step 21: f(x)= 9544.928277820545
# differential_evolution step 22: f(x)= 9544.928277820545
# differential_evolution step 23: f(x)= 9544.928277820545
# differential_evolution step 24: f(x)= 9544.928277820545
# differential_evolution step 25: f(x)= 9544.928277820545
# differential_evolution step 26: f(x)= 3770.47173019773
# differential_evolution step 27: f(x)= 3770.47173019773
# differential_evolution step 28: f(x)= 3770.47173019773
# differential_evolution step 29: f(x)= 3770.47173019773
# differential_evolution step 30: f(x)= 3770.47173019773
# differential_evolution step 31: f(x)= 3770.47173019773
# differential_evolution step 32: f(x)= 3518.2946013623155
# differential_evolution step 33: f(x)= 3518.2946013623155
# differential_evolution step 34: f(x)= 1321.4259611459383
# differential_evolution step 35: f(x)= 1321.4259611459383
# differential_evolution step 36: f(x)= 1321.4259611459383
# differential_evolution step 37: f(x)= 1321.4259611459383
# differential_evolution step 38: f(x)= 1321.4259611459383
# differential_evolution step 39: f(x)= 1321.4259611459383
# differential_evolution step 40: f(x)= 1321.4259611459383
# differential_evolution step 41: f(x)= 1321.4259611459383
# differential_evolution step 42: f(x)= 1321.4259611459383
# differential_evolution step 43: f(x)= 1224.92631644063
# differential_evolution step 44: f(x)= 1224.92631644063
# differential_evolution step 45: f(x)= 1224.92631644063
# differential_evolution step 46: f(x)= 1224.92631644063
# differential_evolution step 47: f(x)= 894.3128249804146
# differential_evolution step 48: f(x)= 894.3128249804146
# differential_evolution step 49: f(x)= 894.3128249804146
# differential_evolution step 50: f(x)= 894.3128249804146
# differential_evolution step 51: f(x)= 894.3128249804146
# differential_evolution step 52: f(x)= 894.3128249804146
# differential_evolution step 53: f(x)= 894.3128249804146
# differential_evolution step 54: f(x)= 894.3128249804146
# differential_evolution step 55: f(x)= 894.3128249804146
# differential_evolution step 56: f(x)= 894.3128249804146
# differential_evolution step 57: f(x)= 798.0818391089693
# differential_evolution step 58: f(x)= 230.69564509473517
# differential_evolution step 59: f(x)= 230.69564509473517
# differential_evolution step 60: f(x)= 230.69564509473517
# differential_evolution step 61: f(x)= 230.69564509473517
# differential_evolution step 62: f(x)= 230.69564509473517
# differential_evolution step 63: f(x)= 230.69564509473517
# differential_evolution step 64: f(x)= 230.69564509473517
# differential_evolution step 65: f(x)= 230.69564509473517
# differential_evolution step 66: f(x)= 230.69564509473517
# differential_evolution step 67: f(x)= 230.69564509473517
# differential_evolution step 68: f(x)= 230.69564509473517
# differential_evolution step 69: f(x)= 230.69564509473517
# differential_evolution step 70: f(x)= 193.677757778142
# differential_evolution step 71: f(x)= 193.677757778142
# differential_evolution step 72: f(x)= 193.677757778142
# differential_evolution step 73: f(x)= 193.677757778142
# differential_evolution step 74: f(x)= 193.677757778142
# differential_evolution step 75: f(x)= 193.677757778142
# differential_evolution step 76: f(x)= 193.677757778142
# differential_evolution step 77: f(x)= 193.677757778142
# differential_evolution step 78: f(x)= 193.677757778142
# differential_evolution step 79: f(x)= 193.677757778142
# differential_evolution step 80: f(x)= 193.677757778142
# differential_evolution step 81: f(x)= 193.677757778142
# differential_evolution step 82: f(x)= 193.677757778142
# differential_evolution step 83: f(x)= 193.677757778142
# differential_evolution step 84: f(x)= 193.677757778142
# differential_evolution step 85: f(x)= 193.677757778142
# differential_evolution step 86: f(x)= 193.677757778142
# differential_evolution step 87: f(x)= 193.677757778142
# differential_evolution step 88: f(x)= 193.677757778142
# differential_evolution step 89: f(x)= 193.677757778142
# differential_evolution step 90: f(x)= 193.677757778142
# differential_evolution step 91: f(x)= 193.677757778142
# differential_evolution step 92: f(x)= 193.677757778142
# differential_evolution step 93: f(x)= 193.677757778142
# differential_evolution step 94: f(x)= 193.677757778142
# differential_evolution step 95: f(x)= 193.677757778142
# differential_evolution step 96: f(x)= 193.677757778142
# differential_evolution step 97: f(x)= 193.677757778142
# differential_evolution step 98: f(x)= 193.677757778142
# differential_evolution step 99: f(x)= 193.677757778142
# differential_evolution step 100: f(x)= 193.677757778142
# differential_evolution step 101: f(x)= 193.677757778142
# differential_evolution step 102: f(x)= 193.677757778142
# differential_evolution step 103: f(x)= 193.677757778142
# differential_evolution step 104: f(x)= 193.677757778142
# differential_evolution step 105: f(x)= 193.677757778142
# differential_evolution step 106: f(x)= 193.677757778142
# differential_evolution step 107: f(x)= 193.677757778142
# differential_evolution step 108: f(x)= 193.677757778142
# differential_evolution step 109: f(x)= 193.677757778142
# differential_evolution step 110: f(x)= 193.677757778142
# differential_evolution step 111: f(x)= 193.677757778142
# differential_evolution step 112: f(x)= 193.677757778142
# differential_evolution step 113: f(x)= 193.677757778142
# differential_evolution step 114: f(x)= 193.677757778142
# differential_evolution step 115: f(x)= 193.677757778142
# differential_evolution step 116: f(x)= 193.677757778142
# differential_evolution step 117: f(x)= 193.677757778142
# differential_evolution step 118: f(x)= 193.677757778142
# differential_evolution step 119: f(x)= 193.677757778142
# differential_evolution step 120: f(x)= 193.677757778142
# differential_evolution step 121: f(x)= 193.677757778142
# differential_evolution step 122: f(x)= 193.677757778142
# differential_evolution step 123: f(x)= 193.677757778142
# differential_evolution step 124: f(x)= 128.0676714586511
# differential_evolution step 125: f(x)= 128.0676714586511
# differential_evolution step 126: f(x)= 128.0676714586511
# differential_evolution step 127: f(x)= 63.748081940510325
# differential_evolution step 128: f(x)= 63.748081940510325
# differential_evolution step 129: f(x)= 63.748081940510325
# differential_evolution step 130: f(x)= 63.748081940510325
# differential_evolution step 131: f(x)= 63.748081940510325
# differential_evolution step 132: f(x)= 63.748081940510325
# differential_evolution step 133: f(x)= 63.748081940510325
# differential_evolution step 134: f(x)= 63.748081940510325
# differential_evolution step 135: f(x)= 63.748081940510325
# differential_evolution step 136: f(x)= 63.748081940510325
# differential_evolution step 137: f(x)= 63.748081940510325
# differential_evolution step 138: f(x)= 63.748081940510325
# differential_evolution step 139: f(x)= 63.748081940510325
# differential_evolution step 140: f(x)= 63.748081940510325
# differential_evolution step 141: f(x)= 57.75861982172726
# differential_evolution step 142: f(x)= 57.75861982172726
# differential_evolution step 143: f(x)= 57.75861982172726
# differential_evolution step 144: f(x)= 57.75861982172726
# differential_evolution step 145: f(x)= 57.75861982172726
# differential_evolution step 146: f(x)= 54.31817832773214
# differential_evolution step 147: f(x)= 54.31817832773214
# differential_evolution step 148: f(x)= 54.31817832773214
# differential_evolution step 149: f(x)= 54.31817832773214
# differential_evolution step 150: f(x)= 54.31817832773214
# differential_evolution step 151: f(x)= 54.31817832773214
# differential_evolution step 152: f(x)= 54.31817832773214
# differential_evolution step 153: f(x)= 54.31817832773214
# differential_evolution step 154: f(x)= 54.31817832773214
# differential_evolution step 155: f(x)= 54.31817832773214
# differential_evolution step 156: f(x)= 54.31817832773214
# differential_evolution step 157: f(x)= 54.31817832773214
# differential_evolution step 158: f(x)= 54.31817832773214
# differential_evolution step 159: f(x)= 54.31817832773214
# differential_evolution step 160: f(x)= 54.31817832773214
# differential_evolution step 161: f(x)= 54.31817832773214
# differential_evolution step 162: f(x)= 54.31817832773214
# differential_evolution step 163: f(x)= 54.31817832773214
# differential_evolution step 164: f(x)= 54.31817832773214
# differential_evolution step 165: f(x)= 54.31817832773214
# differential_evolution step 166: f(x)= 54.31817832773214
# differential_evolution step 167: f(x)= 54.31817832773214
# differential_evolution step 168: f(x)= 54.31817832773214
# differential_evolution step 169: f(x)= 54.31817832773214
# differential_evolution step 170: f(x)= 54.31817832773214
# differential_evolution step 171: f(x)= 54.31817832773214
# differential_evolution step 172: f(x)= 19.61904472634921
# differential_evolution step 173: f(x)= 19.61904472634921
# differential_evolution step 174: f(x)= 19.61904472634921
# differential_evolution step 175: f(x)= 19.61904472634921
# differential_evolution step 176: f(x)= 19.61904472634921
# differential_evolution step 177: f(x)= 19.61904472634921
# differential_evolution step 178: f(x)= 19.61904472634921
# differential_evolution step 179: f(x)= 19.61904472634921
# differential_evolution step 180: f(x)= 19.61904472634921
# differential_evolution step 181: f(x)= 19.61904472634921
# differential_evolution step 182: f(x)= 19.61904472634921
# differential_evolution step 183: f(x)= 19.61904472634921
# differential_evolution step 184: f(x)= 19.61904472634921
# differential_evolution step 185: f(x)= 19.61904472634921
# differential_evolution step 186: f(x)= 19.61904472634921
# differential_evolution step 187: f(x)= 19.61904472634921
# differential_evolution step 188: f(x)= 19.61904472634921
# differential_evolution step 189: f(x)= 19.61904472634921
# differential_evolution step 190: f(x)= 19.61904472634921
# differential_evolution step 191: f(x)= 19.61904472634921
# differential_evolution step 192: f(x)= 19.61904472634921
# differential_evolution step 193: f(x)= 19.61904472634921
# differential_evolution step 194: f(x)= 19.61904472634921
# differential_evolution step 195: f(x)= 19.61904472634921
# differential_evolution step 196: f(x)= 19.61904472634921
# differential_evolution step 197: f(x)= 19.61904472634921
# differential_evolution step 198: f(x)= 18.432974505259786
# differential_evolution step 199: f(x)= 18.432974505259786
# differential_evolution step 200: f(x)= 18.432974505259786
# differential_evolution step 201: f(x)= 18.432974505259786
# differential_evolution step 202: f(x)= 18.432974505259786
# differential_evolution step 203: f(x)= 18.432974505259786
# differential_evolution step 204: f(x)= 18.432974505259786
# differential_evolution step 205: f(x)= 18.432974505259786
# differential_evolution step 206: f(x)= 18.432974505259786
# differential_evolution step 207: f(x)= 18.432974505259786
# differential_evolution step 208: f(x)= 18.432974505259786
# differential_evolution step 209: f(x)= 18.432974505259786
# differential_evolution step 210: f(x)= 18.432974505259786
# differential_evolution step 211: f(x)= 18.432974505259786
# differential_evolution step 212: f(x)= 18.432974505259786
# differential_evolution step 213: f(x)= 15.70144451747183
# differential_evolution step 214: f(x)= 15.70144451747183
# differential_evolution step 215: f(x)= 15.70144451747183
# differential_evolution step 216: f(x)= 15.70144451747183
# differential_evolution step 217: f(x)= 15.70144451747183
# differential_evolution step 218: f(x)= 15.70144451747183
# differential_evolution step 219: f(x)= 15.70144451747183
# differential_evolution step 220: f(x)= 15.70144451747183
# differential_evolution step 221: f(x)= 15.70144451747183
# differential_evolution step 222: f(x)= 15.70144451747183
# differential_evolution step 223: f(x)= 14.841940428783229
# differential_evolution step 224: f(x)= 14.841940428783229
# differential_evolution step 225: f(x)= 14.841940428783229
# differential_evolution step 226: f(x)= 14.841940428783229
# differential_evolution step 227: f(x)= 14.699997265886195
# differential_evolution step 228: f(x)= 14.699997265886195
# differential_evolution step 229: f(x)= 14.699997265886195
# differential_evolution step 230: f(x)= 14.699997265886195
# differential_evolution step 231: f(x)= 14.699997265886195
# differential_evolution step 232: f(x)= 14.699997265886195
# differential_evolution step 233: f(x)= 14.699997265886195
# differential_evolution step 234: f(x)= 14.699997265886195
# differential_evolution step 235: f(x)= 14.699997265886195
# differential_evolution step 236: f(x)= 12.898679401807726
# differential_evolution step 237: f(x)= 12.898679401807726
# differential_evolution step 238: f(x)= 12.898679401807726
# differential_evolution step 239: f(x)= 12.898679401807726
# differential_evolution step 240: f(x)= 12.898679401807726
# differential_evolution step 241: f(x)= 12.898679401807726
# differential_evolution step 242: f(x)= 12.898679401807726
# differential_evolution step 243: f(x)= 12.898679401807726
# differential_evolution step 244: f(x)= 12.898679401807726
# differential_evolution step 245: f(x)= 12.898679401807726
# differential_evolution step 246: f(x)= 12.898679401807726
# differential_evolution step 247: f(x)= 10.471913290415639
# differential_evolution step 248: f(x)= 10.471913290415639
# differential_evolution step 249: f(x)= 10.471913290415639
# differential_evolution step 250: f(x)= 10.471913290415639
# differential_evolution step 251: f(x)= 10.471913290415639
# differential_evolution step 252: f(x)= 10.471913290415639
# differential_evolution step 253: f(x)= 10.471913290415639
# differential_evolution step 254: f(x)= 10.471913290415639
# differential_evolution step 255: f(x)= 10.471913290415639
# differential_evolution step 256: f(x)= 10.471913290415639
# differential_evolution step 257: f(x)= 10.471913290415639
# differential_evolution step 258: f(x)= 10.471913290415639
# differential_evolution step 259: f(x)= 10.471913290415639
# differential_evolution step 260: f(x)= 10.471913290415639
# differential_evolution step 261: f(x)= 10.349808379771533
# differential_evolution step 262: f(x)= 9.371653447523961
# differential_evolution step 263: f(x)= 9.371653447523961
# differential_evolution step 264: f(x)= 9.371653447523961
# differential_evolution step 265: f(x)= 9.371653447523961
# differential_evolution step 266: f(x)= 9.371653447523961
# differential_evolution step 267: f(x)= 9.371653447523961
# differential_evolution step 268: f(x)= 9.371653447523961
# differential_evolution step 269: f(x)= 9.371653447523961
# differential_evolution step 270: f(x)= 7.672368983366504
# differential_evolution step 271: f(x)= 7.672368983366504
# differential_evolution step 272: f(x)= 7.672368983366504
# differential_evolution step 273: f(x)= 7.672368983366504
# differential_evolution step 274: f(x)= 7.672368983366504
# differential_evolution step 275: f(x)= 7.672368983366504
# differential_evolution step 276: f(x)= 7.672368983366504
# differential_evolution step 277: f(x)= 7.672368983366504
# differential_evolution step 278: f(x)= 7.672368983366504
# differential_evolution step 279: f(x)= 7.672368983366504
# differential_evolution step 280: f(x)= 7.672368983366504
# differential_evolution step 281: f(x)= 7.672368983366504
# differential_evolution step 282: f(x)= 7.672368983366504
# differential_evolution step 283: f(x)= 6.97698877820867
# differential_evolution step 284: f(x)= 6.97698877820867
# differential_evolution step 285: f(x)= 6.97698877820867
# differential_evolution step 286: f(x)= 6.97698877820867
# differential_evolution step 287: f(x)= 6.97698877820867
# differential_evolution step 288: f(x)= 6.97698877820867
# differential_evolution step 289: f(x)= 6.97698877820867
# differential_evolution step 290: f(x)= 6.97698877820867
# differential_evolution step 291: f(x)= 6.97698877820867
# differential_evolution step 292: f(x)= 6.97698877820867
# differential_evolution step 293: f(x)= 6.97698877820867
# differential_evolution step 294: f(x)= 6.97698877820867
# differential_evolution step 295: f(x)= 6.97698877820867
# differential_evolution step 296: f(x)= 6.97698877820867
# differential_evolution step 297: f(x)= 6.97698877820867
# differential_evolution step 298: f(x)= 6.97698877820867
# differential_evolution step 299: f(x)= 6.97698877820867
# differential_evolution step 300: f(x)= 6.97698877820867
# differential_evolution step 301: f(x)= 6.577018129851236
# differential_evolution step 302: f(x)= 6.577018129851236
# differential_evolution step 303: f(x)= 6.577018129851236
# differential_evolution step 304: f(x)= 3.321623962765949
# differential_evolution step 305: f(x)= 3.321623962765949
# differential_evolution step 306: f(x)= 3.321623962765949
# differential_evolution step 307: f(x)= 3.321623962765949
# differential_evolution step 308: f(x)= 3.321623962765949
# differential_evolution step 309: f(x)= 3.321623962765949
# differential_evolution step 310: f(x)= 3.321623962765949
# differential_evolution step 311: f(x)= 3.321623962765949
# differential_evolution step 312: f(x)= 3.321623962765949
# differential_evolution step 313: f(x)= 3.321623962765949
# differential_evolution step 314: f(x)= 3.321623962765949
# differential_evolution step 315: f(x)= 3.321623962765949
# differential_evolution step 316: f(x)= 3.321623962765949
# differential_evolution step 317: f(x)= 3.321623962765949
# differential_evolution step 318: f(x)= 3.321623962765949
# differential_evolution step 319: f(x)= 3.321623962765949
# differential_evolution step 320: f(x)= 3.321623962765949
# differential_evolution step 321: f(x)= 3.321623962765949
# differential_evolution step 322: f(x)= 3.321623962765949
# differential_evolution step 323: f(x)= 3.321623962765949
# differential_evolution step 324: f(x)= 3.321623962765949
# differential_evolution step 325: f(x)= 3.321623962765949
# differential_evolution step 326: f(x)= 3.321623962765949
# differential_evolution step 327: f(x)= 3.321623962765949
# differential_evolution step 328: f(x)= 3.321623962765949
# differential_evolution step 329: f(x)= 3.321623962765949
# differential_evolution step 330: f(x)= 3.321623962765949
# differential_evolution step 331: f(x)= 3.321623962765949
# differential_evolution step 332: f(x)= 3.321623962765949
# differential_evolution step 333: f(x)= 3.321623962765949
# differential_evolution step 334: f(x)= 3.321623962765949
# differential_evolution step 335: f(x)= 3.1777064315754444
# differential_evolution step 336: f(x)= 3.1777064315754444
# differential_evolution step 337: f(x)= 3.1777064315754444
# differential_evolution step 338: f(x)= 3.1777064315754444
# differential_evolution step 339: f(x)= 3.1777064315754444
# differential_evolution step 340: f(x)= 3.1777064315754444
# differential_evolution step 341: f(x)= 3.1777064315754444
# differential_evolution step 342: f(x)= 3.1777064315754444
# differential_evolution step 343: f(x)= 3.1777064315754444
# differential_evolution step 344: f(x)= 3.1777064315754444
# differential_evolution step 345: f(x)= 2.534127913873185
# differential_evolution step 346: f(x)= 2.534127913873185
# differential_evolution step 347: f(x)= 2.534127913873185
# differential_evolution step 348: f(x)= 2.534127913873185
# differential_evolution step 349: f(x)= 2.534127913873185
# differential_evolution step 350: f(x)= 2.534127913873185
# differential_evolution step 351: f(x)= 2.2297707839121843
# differential_evolution step 352: f(x)= 2.2297707839121843
# differential_evolution step 353: f(x)= 2.2297707839121843
# differential_evolution step 354: f(x)= 2.2297707839121843
# differential_evolution step 355: f(x)= 2.2297707839121843
# differential_evolution step 356: f(x)= 2.2297707839121843
# differential_evolution step 357: f(x)= 2.2297707839121843
# differential_evolution step 358: f(x)= 2.2297707839121843
# differential_evolution step 359: f(x)= 2.2297707839121843
# differential_evolution step 360: f(x)= 2.2297707839121843
# differential_evolution step 361: f(x)= 2.2297707839121843
# differential_evolution step 362: f(x)= 2.2297707839121843
# differential_evolution step 363: f(x)= 2.2297707839121843
# differential_evolution step 364: f(x)= 2.2297707839121843
# differential_evolution step 365: f(x)= 2.111054059625621
# differential_evolution step 366: f(x)= 2.111054059625621
# differential_evolution step 367: f(x)= 2.111054059625621
# differential_evolution step 368: f(x)= 2.111054059625621
# differential_evolution step 369: f(x)= 2.111054059625621
# differential_evolution step 370: f(x)= 2.111054059625621
# differential_evolution step 371: f(x)= 2.111054059625621
# differential_evolution step 372: f(x)= 2.111054059625621
# differential_evolution step 373: f(x)= 2.111054059625621
# differential_evolution step 374: f(x)= 2.111054059625621
# differential_evolution step 375: f(x)= 2.111054059625621
# differential_evolution step 376: f(x)= 2.111054059625621
# differential_evolution step 377: f(x)= 2.111054059625621
# differential_evolution step 378: f(x)= 2.111054059625621
# differential_evolution step 379: f(x)= 2.111054059625621
# differential_evolution step 380: f(x)= 2.111054059625621
# differential_evolution step 381: f(x)= 2.111054059625621
# differential_evolution step 382: f(x)= 2.111054059625621
# differential_evolution step 383: f(x)= 1.960175844459746
# differential_evolution step 384: f(x)= 1.960175844459746
# differential_evolution step 385: f(x)= 1.960175844459746
# differential_evolution step 386: f(x)= 1.960175844459746
# differential_evolution step 387: f(x)= 1.960175844459746
# differential_evolution step 388: f(x)= 1.960175844459746
# differential_evolution step 389: f(x)= 1.960175844459746
# differential_evolution step 390: f(x)= 1.960175844459746
# differential_evolution step 391: f(x)= 1.960175844459746
# differential_evolution step 392: f(x)= 1.960175844459746
# differential_evolution step 393: f(x)= 1.960175844459746
# differential_evolution step 394: f(x)= 1.960175844459746
# differential_evolution step 395: f(x)= 1.960175844459746
# differential_evolution step 396: f(x)= 1.960175844459746
# differential_evolution step 397: f(x)= 1.960175844459746
# differential_evolution step 398: f(x)= 1.960175844459746
# differential_evolution step 399: f(x)= 1.7109084738069644
# differential_evolution step 400: f(x)= 1.7109084738069644
# differential_evolution step 401: f(x)= 1.7109084738069644
# differential_evolution step 402: f(x)= 1.7109084738069644
# differential_evolution step 403: f(x)= 1.7109084738069644
# differential_evolution step 404: f(x)= 1.7109084738069644
# differential_evolution step 405: f(x)= 1.6917702905458982
# differential_evolution step 406: f(x)= 1.6917702905458982
# differential_evolution step 407: f(x)= 1.6917702905458982
# differential_evolution step 408: f(x)= 1.6917702905458982
# differential_evolution step 409: f(x)= 1.6917702905458982
# differential_evolution step 410: f(x)= 1.6917702905458982
# differential_evolution step 411: f(x)= 1.6917702905458982
# differential_evolution step 412: f(x)= 1.5784901629076786
# differential_evolution step 413: f(x)= 1.5784901629076786
# differential_evolution step 414: f(x)= 1.501291905651409
# differential_evolution step 415: f(x)= 1.501291905651409
# differential_evolution step 416: f(x)= 1.501291905651409
# differential_evolution step 417: f(x)= 1.501291905651409
# differential_evolution step 418: f(x)= 1.501291905651409
# differential_evolution step 419: f(x)= 1.501291905651409
# differential_evolution step 420: f(x)= 1.501291905651409
# differential_evolution step 421: f(x)= 1.501291905651409
# differential_evolution step 422: f(x)= 1.501291905651409
# differential_evolution step 423: f(x)= 1.501291905651409
# differential_evolution step 424: f(x)= 1.501291905651409
# differential_evolution step 425: f(x)= 1.501291905651409
# differential_evolution step 426: f(x)= 1.501291905651409
# differential_evolution step 427: f(x)= 1.501291905651409
# differential_evolution step 428: f(x)= 1.501291905651409
# differential_evolution step 429: f(x)= 1.501291905651409
# differential_evolution step 430: f(x)= 1.501291905651409
# differential_evolution step 431: f(x)= 1.501291905651409
# differential_evolution step 432: f(x)= 1.501291905651409
# differential_evolution step 433: f(x)= 1.501291905651409
# differential_evolution step 434: f(x)= 1.501291905651409
# differential_evolution step 435: f(x)= 1.501291905651409
# differential_evolution step 436: f(x)= 1.501291905651409
# differential_evolution step 437: f(x)= 1.501291905651409
# differential_evolution step 438: f(x)= 1.501291905651409
# differential_evolution step 439: f(x)= 1.501291905651409
# differential_evolution step 440: f(x)= 1.501291905651409
# differential_evolution step 441: f(x)= 1.501291905651409
# differential_evolution step 442: f(x)= 1.501291905651409
# differential_evolution step 443: f(x)= 1.501291905651409
# differential_evolution step 444: f(x)= 1.501291905651409
# differential_evolution step 445: f(x)= 1.501291905651409
# differential_evolution step 446: f(x)= 1.501291905651409
# differential_evolution step 447: f(x)= 1.501291905651409
# differential_evolution step 448: f(x)= 1.3698025251476755
# differential_evolution step 449: f(x)= 1.3698025251476755
# differential_evolution step 450: f(x)= 1.3698025251476755
# differential_evolution step 451: f(x)= 1.3698025251476755
# differential_evolution step 452: f(x)= 1.3698025251476755
# differential_evolution step 453: f(x)= 1.3698025251476755
# differential_evolution step 454: f(x)= 1.3698025251476755
# differential_evolution step 455: f(x)= 1.3698025251476755
# differential_evolution step 456: f(x)= 1.3698025251476755
# differential_evolution step 457: f(x)= 1.3698025251476755
# differential_evolution step 458: f(x)= 1.3698025251476755
# differential_evolution step 459: f(x)= 1.3698025251476755
# differential_evolution step 460: f(x)= 1.3698025251476755
# differential_evolution step 461: f(x)= 1.3698025251476755
# differential_evolution step 462: f(x)= 1.3698025251476755
# differential_evolution step 463: f(x)= 1.3698025251476755
# differential_evolution step 464: f(x)= 1.3698025251476755
# differential_evolution step 465: f(x)= 1.3698025251476755
# differential_evolution step 466: f(x)= 1.3698025251476755
# differential_evolution step 467: f(x)= 1.3698025251476755
# differential_evolution step 468: f(x)= 1.3698025251476755
# differential_evolution step 469: f(x)= 1.3698025251476755
# differential_evolution step 470: f(x)= 1.3698025251476755
# differential_evolution step 471: f(x)= 1.3698025251476755
# differential_evolution step 472: f(x)= 1.3698025251476755
# differential_evolution step 473: f(x)= 1.3698025251476755
# differential_evolution step 474: f(x)= 1.3698025251476755
# differential_evolution step 475: f(x)= 1.3698025251476755
# differential_evolution step 476: f(x)= 1.3698025251476755
# differential_evolution step 477: f(x)= 1.3698025251476755
# differential_evolution step 478: f(x)= 1.3698025251476755
# differential_evolution step 479: f(x)= 1.3698025251476755
# differential_evolution step 480: f(x)= 1.3698025251476755
# differential_evolution step 481: f(x)= 1.3698025251476755
# differential_evolution step 482: f(x)= 1.338713952064102
# differential_evolution step 483: f(x)= 1.338713952064102
# differential_evolution step 484: f(x)= 1.3213671189199765
# differential_evolution step 485: f(x)= 1.3213671189199765
# differential_evolution step 486: f(x)= 1.3213671189199765
# differential_evolution step 487: f(x)= 1.3213671189199765
# differential_evolution step 488: f(x)= 1.3213671189199765
# differential_evolution step 489: f(x)= 1.3213671189199765
# differential_evolution step 490: f(x)= 1.3213671189199765
# differential_evolution step 491: f(x)= 1.3213671189199765
# differential_evolution step 492: f(x)= 1.3213671189199765
# differential_evolution step 493: f(x)= 1.3213671189199765
# differential_evolution step 494: f(x)= 1.3213671189199765
# differential_evolution step 495: f(x)= 1.3213671189199765
# differential_evolution step 496: f(x)= 1.3213671189199765
# differential_evolution step 497: f(x)= 1.3213671189199765
# differential_evolution step 498: f(x)= 1.3213671189199765
# differential_evolution step 499: f(x)= 1.3213671189199765
# differential_evolution step 500: f(x)= 1.3213671189199765
# differential_evolution step 501: f(x)= 1.3213671189199765
# differential_evolution step 502: f(x)= 1.3213671189199765
# differential_evolution step 503: f(x)= 1.3213671189199765
# differential_evolution step 504: f(x)= 1.3213671189199765
# differential_evolution step 505: f(x)= 1.3213671189199765
# differential_evolution step 506: f(x)= 1.3213671189199765
# differential_evolution step 507: f(x)= 1.3213671189199765
# differential_evolution step 508: f(x)= 1.2747165277413055
# differential_evolution step 509: f(x)= 1.2747165277413055
# differential_evolution step 510: f(x)= 1.2747165277413055
# differential_evolution step 511: f(x)= 1.2747165277413055
# differential_evolution step 512: f(x)= 1.2747165277413055
# differential_evolution step 513: f(x)= 1.2747165277413055
# differential_evolution step 514: f(x)= 1.1979402116876694
# differential_evolution step 515: f(x)= 1.1979402116876694
# differential_evolution step 516: f(x)= 1.1979402116876694
# differential_evolution step 517: f(x)= 1.1979402116876694
# differential_evolution step 518: f(x)= 1.1979402116876694
# differential_evolution step 519: f(x)= 1.1979402116876694
# differential_evolution step 520: f(x)= 1.1979402116876694
# differential_evolution step 521: f(x)= 1.1979402116876694
# differential_evolution step 522: f(x)= 1.1979402116876694
# differential_evolution step 523: f(x)= 1.1979402116876694
# differential_evolution step 524: f(x)= 1.1979402116876694
# differential_evolution step 525: f(x)= 1.1979402116876694
# differential_evolution step 526: f(x)= 1.1979402116876694
# differential_evolution step 527: f(x)= 1.1979402116876694
# differential_evolution step 528: f(x)= 1.0372018855031995
# differential_evolution step 529: f(x)= 1.0372018855031995
# differential_evolution step 530: f(x)= 1.003973163075574
# differential_evolution step 531: f(x)= 1.003973163075574
# differential_evolution step 532: f(x)= 1.003973163075574
# differential_evolution step 533: f(x)= 1.003973163075574
# differential_evolution step 534: f(x)= 1.003973163075574
# differential_evolution step 535: f(x)= 1.003973163075574
# differential_evolution step 536: f(x)= 1.003973163075574
# differential_evolution step 537: f(x)= 1.003973163075574
# differential_evolution step 538: f(x)= 1.003973163075574
# differential_evolution step 539: f(x)= 1.003973163075574
# differential_evolution step 540: f(x)= 1.003973163075574
# differential_evolution step 541: f(x)= 1.003973163075574
# differential_evolution step 542: f(x)= 0.908279992817006
# differential_evolution step 543: f(x)= 0.908279992817006
# differential_evolution step 544: f(x)= 0.908279992817006
# differential_evolution step 545: f(x)= 0.908279992817006
# differential_evolution step 546: f(x)= 0.908279992817006
# differential_evolution step 547: f(x)= 0.908279992817006
# differential_evolution step 548: f(x)= 0.908279992817006
# differential_evolution step 549: f(x)= 0.908279992817006
# differential_evolution step 550: f(x)= 0.908279992817006
# differential_evolution step 551: f(x)= 0.908279992817006
# differential_evolution step 552: f(x)= 0.908279992817006
# differential_evolution step 553: f(x)= 0.908279992817006
# differential_evolution step 554: f(x)= 0.908279992817006
# differential_evolution step 555: f(x)= 0.908279992817006
# differential_evolution step 556: f(x)= 0.908279992817006
# differential_evolution step 557: f(x)= 0.9077889220343557
# differential_evolution step 558: f(x)= 0.9077889220343557
# differential_evolution step 559: f(x)= 0.9077889220343557
# differential_evolution step 560: f(x)= 0.9077889220343557
# differential_evolution step 561: f(x)= 0.9077889220343557
# differential_evolution step 562: f(x)= 0.9077889220343557
# differential_evolution step 563: f(x)= 0.9077889220343557
# differential_evolution step 564: f(x)= 0.9077889220343557
# differential_evolution step 565: f(x)= 0.9077889220343557
# differential_evolution step 566: f(x)= 0.9077889220343557
# differential_evolution step 567: f(x)= 0.9077889220343557
# differential_evolution step 568: f(x)= 0.9077889220343557
# differential_evolution step 569: f(x)= 0.9077889220343557
# differential_evolution step 570: f(x)= 0.9077889220343557
# differential_evolution step 571: f(x)= 0.9077889220343557
# differential_evolution step 572: f(x)= 0.9077889220343557
# differential_evolution step 573: f(x)= 0.9077889220343557
# differential_evolution step 574: f(x)= 0.9077889220343557
# differential_evolution step 575: f(x)= 0.9077889220343557
# differential_evolution step 576: f(x)= 0.9077889220343557
# differential_evolution step 577: f(x)= 0.9077889220343557
# differential_evolution step 578: f(x)= 0.9077889220343557
# differential_evolution step 579: f(x)= 0.8379000447745034
# differential_evolution step 580: f(x)= 0.7303347287390418
# differential_evolution step 581: f(x)= 0.7303347287390418
# differential_evolution step 582: f(x)= 0.7303347287390418
# differential_evolution step 583: f(x)= 0.7303347287390418
# differential_evolution step 584: f(x)= 0.7303347287390418
# differential_evolution step 585: f(x)= 0.7303347287390418
# differential_evolution step 586: f(x)= 0.7303347287390418
# differential_evolution step 587: f(x)= 0.7245634675230113
# differential_evolution step 588: f(x)= 0.7245634675230113
# differential_evolution step 589: f(x)= 0.7245634675230113
# differential_evolution step 590: f(x)= 0.7245634675230113
# differential_evolution step 591: f(x)= 0.7245634675230113
# differential_evolution step 592: f(x)= 0.7245634675230113
# differential_evolution step 593: f(x)= 0.7245634675230113
# differential_evolution step 594: f(x)= 0.7245634675230113
# differential_evolution step 595: f(x)= 0.7245634675230113
# differential_evolution step 596: f(x)= 0.7245634675230113
# differential_evolution step 597: f(x)= 0.7245634675230113
# differential_evolution step 598: f(x)= 0.7245634675230113
# differential_evolution step 599: f(x)= 0.7102555191193023
# differential_evolution step 600: f(x)= 0.7102555191193023
# differential_evolution step 601: f(x)= 0.7102555191193023
# differential_evolution step 602: f(x)= 0.7102555191193023
# differential_evolution step 603: f(x)= 0.7102555191193023
# differential_evolution step 604: f(x)= 0.7102555191193023
# differential_evolution step 605: f(x)= 0.7102555191193023
# differential_evolution step 606: f(x)= 0.7102555191193023
# differential_evolution step 607: f(x)= 0.7102555191193023
# differential_evolution step 608: f(x)= 0.7102555191193023
# differential_evolution step 609: f(x)= 0.7102555191193023
# differential_evolution step 610: f(x)= 0.7102555191193023
# differential_evolution step 611: f(x)= 0.7102555191193023
# differential_evolution step 612: f(x)= 0.7102555191193023
# differential_evolution step 613: f(x)= 0.7102555191193023
# differential_evolution step 614: f(x)= 0.7102555191193023
# differential_evolution step 615: f(x)= 0.7102555191193023
# differential_evolution step 616: f(x)= 0.7102555191193023
# differential_evolution step 617: f(x)= 0.7102555191193023
# differential_evolution step 618: f(x)= 0.7102555191193023
# differential_evolution step 619: f(x)= 0.7102555191193023
# differential_evolution step 620: f(x)= 0.7102555191193023
# differential_evolution step 621: f(x)= 0.7102555191193023
# differential_evolution step 622: f(x)= 0.7102555191193023
# differential_evolution step 623: f(x)= 0.7102555191193023
# differential_evolution step 624: f(x)= 0.7102555191193023
# differential_evolution step 625: f(x)= 0.6713269463348869
# differential_evolution step 626: f(x)= 0.6713269463348869
# differential_evolution step 627: f(x)= 0.6713269463348869
# differential_evolution step 628: f(x)= 0.6713269463348869
# differential_evolution step 629: f(x)= 0.6713269463348869
# differential_evolution step 630: f(x)= 0.6316310340569293
# differential_evolution step 631: f(x)= 0.6316310340569293
# differential_evolution step 632: f(x)= 0.6316310340569293
# differential_evolution step 633: f(x)= 0.6316310340569293
# differential_evolution step 634: f(x)= 0.6316310340569293
# differential_evolution step 635: f(x)= 0.6316310340569293
# differential_evolution step 636: f(x)= 0.6316310340569293
# differential_evolution step 637: f(x)= 0.6316310340569293
# differential_evolution step 638: f(x)= 0.6316310340569293
# differential_evolution step 639: f(x)= 0.6316310340569293
# differential_evolution step 640: f(x)= 0.6316310340569293
# differential_evolution step 641: f(x)= 0.6316310340569293
# differential_evolution step 642: f(x)= 0.6316310340569293
# differential_evolution step 643: f(x)= 0.6316310340569293
# differential_evolution step 644: f(x)= 0.6316310340569293
# differential_evolution step 645: f(x)= 0.6316310340569293
# differential_evolution step 646: f(x)= 0.6316310340569293
# differential_evolution step 647: f(x)= 0.6316310340569293
# differential_evolution step 648: f(x)= 0.6316310340569293
# differential_evolution step 649: f(x)= 0.6316310340569293
# differential_evolution step 650: f(x)= 0.6316310340569293
# differential_evolution step 651: f(x)= 0.6316310340569293
# differential_evolution step 652: f(x)= 0.6316310340569293
# differential_evolution step 653: f(x)= 0.6316310340569293
# differential_evolution step 654: f(x)= 0.6316310340569293
# differential_evolution step 655: f(x)= 0.6316310340569293
# differential_evolution step 656: f(x)= 0.6316310340569293
# differential_evolution step 657: f(x)= 0.6316310340569293
# differential_evolution step 658: f(x)= 0.6316310340569293
# differential_evolution step 659: f(x)= 0.6316310340569293
# differential_evolution step 660: f(x)= 0.6316310340569293
# differential_evolution step 661: f(x)= 0.6316310340569293
# differential_evolution step 662: f(x)= 0.6316310340569293
# differential_evolution step 663: f(x)= 0.6316310340569293
# differential_evolution step 664: f(x)= 0.6316310340569293
# differential_evolution step 665: f(x)= 0.6316310340569293
# differential_evolution step 666: f(x)= 0.6316310340569293
# differential_evolution step 667: f(x)= 0.6316310340569293
# differential_evolution step 668: f(x)= 0.6316310340569293
# differential_evolution step 669: f(x)= 0.6316310340569293
# differential_evolution step 670: f(x)= 0.6252486887908364
# differential_evolution step 671: f(x)= 0.6252486887908364
# differential_evolution step 672: f(x)= 0.6252486887908364
# differential_evolution step 673: f(x)= 0.5247194118904625
# differential_evolution step 674: f(x)= 0.5247194118904625
# differential_evolution step 675: f(x)= 0.5247194118904625
# differential_evolution step 676: f(x)= 0.5247194118904625
# differential_evolution step 677: f(x)= 0.5247194118904625
# differential_evolution step 678: f(x)= 0.5247194118904625
# differential_evolution step 679: f(x)= 0.5247194118904625
# differential_evolution step 680: f(x)= 0.5247194118904625
# differential_evolution step 681: f(x)= 0.5247194118904625
# differential_evolution step 682: f(x)= 0.5247194118904625
# differential_evolution step 683: f(x)= 0.5247194118904625
# differential_evolution step 684: f(x)= 0.5247194118904625
# differential_evolution step 685: f(x)= 0.5247194118904625
# differential_evolution step 686: f(x)= 0.5247194118904625
# differential_evolution step 687: f(x)= 0.5247194118904625
# differential_evolution step 688: f(x)= 0.5247194118904625
# differential_evolution step 689: f(x)= 0.5247194118904625
# differential_evolution step 690: f(x)= 0.5247194118904625
# differential_evolution step 691: f(x)= 0.5247194118904625
# differential_evolution step 692: f(x)= 0.5247194118904625
# differential_evolution step 693: f(x)= 0.5247194118904625
# differential_evolution step 694: f(x)= 0.5247194118904625
# differential_evolution step 695: f(x)= 0.5247194118904625
# differential_evolution step 696: f(x)= 0.5247194118904625
# differential_evolution step 697: f(x)= 0.5247194118904625
# differential_evolution step 698: f(x)= 0.5247194118904625
# differential_evolution step 699: f(x)= 0.5247194118904625
# differential_evolution step 700: f(x)= 0.5247194118904625
# differential_evolution step 701: f(x)= 0.5247194118904625
# differential_evolution step 702: f(x)= 0.5247194118904625
# differential_evolution step 703: f(x)= 0.5247194118904625
# differential_evolution step 704: f(x)= 0.5247194118904625
# differential_evolution step 705: f(x)= 0.5147946322757829
# differential_evolution step 706: f(x)= 0.5147946322757829
# differential_evolution step 707: f(x)= 0.5147946322757829
# differential_evolution step 708: f(x)= 0.5147946322757829
# differential_evolution step 709: f(x)= 0.5147946322757829
# differential_evolution step 710: f(x)= 0.5147946322757829
# differential_evolution step 711: f(x)= 0.5147946322757829
# differential_evolution step 712: f(x)= 0.5147946322757829
# differential_evolution step 713: f(x)= 0.5147946322757829
# differential_evolution step 714: f(x)= 0.5147946322757829
# differential_evolution step 715: f(x)= 0.5147946322757829
# differential_evolution step 716: f(x)= 0.5147946322757829
# differential_evolution step 717: f(x)= 0.5147946322757829
# differential_evolution step 718: f(x)= 0.5147946322757829
# differential_evolution step 719: f(x)= 0.5147946322757829
# differential_evolution step 720: f(x)= 0.5147946322757829
# differential_evolution step 721: f(x)= 0.5147946322757829
# differential_evolution step 722: f(x)= 0.5108760564026315
# differential_evolution step 723: f(x)= 0.5108760564026315
# differential_evolution step 724: f(x)= 0.5108760564026315
# differential_evolution step 725: f(x)= 0.5108760564026315
# differential_evolution step 726: f(x)= 0.5108760564026315
# differential_evolution step 727: f(x)= 0.5108760564026315
# differential_evolution step 728: f(x)= 0.5108760564026315
# differential_evolution step 729: f(x)= 0.5108760564026315
# differential_evolution step 730: f(x)= 0.5108760564026315
# differential_evolution step 731: f(x)= 0.5108760564026315
# differential_evolution step 732: f(x)= 0.5108760564026315
# differential_evolution step 733: f(x)= 0.5108760564026315
# differential_evolution step 734: f(x)= 0.5108760564026315
# differential_evolution step 735: f(x)= 0.5108760564026315
# differential_evolution step 736: f(x)= 0.5108760564026315
# differential_evolution step 737: f(x)= 0.5108760564026315
# differential_evolution step 738: f(x)= 0.5108760564026315
# differential_evolution step 739: f(x)= 0.5108760564026315
# differential_evolution step 740: f(x)= 0.5108760564026315
# differential_evolution step 741: f(x)= 0.5108760564026315
# differential_evolution step 742: f(x)= 0.5108760564026315
# differential_evolution step 743: f(x)= 0.5108760564026315
# differential_evolution step 744: f(x)= 0.5108760564026315
# differential_evolution step 745: f(x)= 0.5108760564026315
# differential_evolution step 746: f(x)= 0.5108760564026315
# differential_evolution step 747: f(x)= 0.5108760564026315
# differential_evolution step 748: f(x)= 0.5108760564026315
# differential_evolution step 749: f(x)= 0.5086118349382683
# differential_evolution step 750: f(x)= 0.5086118349382683
# differential_evolution step 751: f(x)= 0.5086118349382683
# differential_evolution step 752: f(x)= 0.5086118349382683
# differential_evolution step 753: f(x)= 0.5086118349382683
# differential_evolution step 754: f(x)= 0.5086118349382683
# differential_evolution step 755: f(x)= 0.5086118349382683
# differential_evolution step 756: f(x)= 0.5086118349382683
# differential_evolution step 757: f(x)= 0.46275571944704363
# differential_evolution step 758: f(x)= 0.4292818762718677
# differential_evolution step 759: f(x)= 0.4292818762718677
# differential_evolution step 760: f(x)= 0.4292818762718677
# differential_evolution step 761: f(x)= 0.4292818762718677
# differential_evolution step 762: f(x)= 0.4292818762718677
# differential_evolution step 763: f(x)= 0.4292818762718677
# differential_evolution step 764: f(x)= 0.4292818762718677
# differential_evolution step 765: f(x)= 0.4292818762718677
# differential_evolution step 766: f(x)= 0.4292818762718677
# differential_evolution step 767: f(x)= 0.4292818762718677
# differential_evolution step 768: f(x)= 0.4292818762718677
# differential_evolution step 769: f(x)= 0.4292818762718677
# differential_evolution step 770: f(x)= 0.4292818762718677
# differential_evolution step 771: f(x)= 0.4292818762718677
# differential_evolution step 772: f(x)= 0.4292818762718677
# differential_evolution step 773: f(x)= 0.4292818762718677
# differential_evolution step 774: f(x)= 0.4292818762718677
# differential_evolution step 775: f(x)= 0.4292818762718677
# differential_evolution step 776: f(x)= 0.4292818762718677
# differential_evolution step 777: f(x)= 0.4292818762718677
# differential_evolution step 778: f(x)= 0.4292818762718677
# differential_evolution step 779: f(x)= 0.4292818762718677
# differential_evolution step 780: f(x)= 0.4292818762718677
# differential_evolution step 781: f(x)= 0.4292818762718677
# differential_evolution step 782: f(x)= 0.4292818762718677
# differential_evolution step 783: f(x)= 0.4292818762718677
# differential_evolution step 784: f(x)= 0.4292818762718677
# differential_evolution step 785: f(x)= 0.4292818762718677
# differential_evolution step 786: f(x)= 0.4292818762718677
# differential_evolution step 787: f(x)= 0.4292818762718677
# differential_evolution step 788: f(x)= 0.4234848641252006
# differential_evolution step 789: f(x)= 0.4234848641252006
# differential_evolution step 790: f(x)= 0.4234848641252006
# differential_evolution step 791: f(x)= 0.4234848641252006
# differential_evolution step 792: f(x)= 0.4234848641252006
# differential_evolution step 793: f(x)= 0.4234848641252006
# differential_evolution step 794: f(x)= 0.4234848641252006
# differential_evolution step 795: f(x)= 0.4234848641252006
# differential_evolution step 796: f(x)= 0.4234848641252006
# differential_evolution step 797: f(x)= 0.4234848641252006
# differential_evolution step 798: f(x)= 0.4234848641252006
# differential_evolution step 799: f(x)= 0.4234848641252006
# differential_evolution step 800: f(x)= 0.4234848641252006
# differential_evolution step 801: f(x)= 0.4234848641252006
# differential_evolution step 802: f(x)= 0.4234848641252006
# differential_evolution step 803: f(x)= 0.4234848641252006
# differential_evolution step 804: f(x)= 0.4234848641252006
# differential_evolution step 805: f(x)= 0.4234848641252006
# differential_evolution step 806: f(x)= 0.4234848641252006
# differential_evolution step 807: f(x)= 0.4234848641252006
# differential_evolution step 808: f(x)= 0.4234848641252006
# differential_evolution step 809: f(x)= 0.4234848641252006
# differential_evolution step 810: f(x)= 0.4234848641252006
# differential_evolution step 811: f(x)= 0.4234848641252006
# differential_evolution step 812: f(x)= 0.4234848641252006
# differential_evolution step 813: f(x)= 0.4234848641252006
# differential_evolution step 814: f(x)= 0.4234848641252006
# differential_evolution step 815: f(x)= 0.4234848641252006
# differential_evolution step 816: f(x)= 0.4234848641252006
# differential_evolution step 817: f(x)= 0.4234848641252006
# differential_evolution step 818: f(x)= 0.4234848641252006
# differential_evolution step 819: f(x)= 0.4234848641252006
# differential_evolution step 820: f(x)= 0.4234848641252006
# differential_evolution step 821: f(x)= 0.4234848641252006
# differential_evolution step 822: f(x)= 0.4234848641252006
# differential_evolution step 823: f(x)= 0.4234848641252006
# differential_evolution step 824: f(x)= 0.4234848641252006
# differential_evolution step 825: f(x)= 0.4234848641252006
# differential_evolution step 826: f(x)= 0.4234848641252006
# differential_evolution step 827: f(x)= 0.4234848641252006
# differential_evolution step 828: f(x)= 0.4234848641252006
# differential_evolution step 829: f(x)= 0.4234848641252006
# differential_evolution step 830: f(x)= 0.4234848641252006
# differential_evolution step 831: f(x)= 0.4234848641252006
# differential_evolution step 832: f(x)= 0.4234848641252006
# differential_evolution step 833: f(x)= 0.4234848641252006
# differential_evolution step 834: f(x)= 0.4234848641252006
# differential_evolution step 835: f(x)= 0.4234848641252006
# differential_evolution step 836: f(x)= 0.4234848641252006
# differential_evolution step 837: f(x)= 0.41257577262460166
# differential_evolution step 838: f(x)= 0.41257577262460166
# differential_evolution step 839: f(x)= 0.41257577262460166
# differential_evolution step 840: f(x)= 0.41257577262460166
# differential_evolution step 841: f(x)= 0.41257577262460166
# differential_evolution step 842: f(x)= 0.41257577262460166
# differential_evolution step 843: f(x)= 0.41257577262460166
# differential_evolution step 844: f(x)= 0.41257577262460166
# differential_evolution step 845: f(x)= 0.41257577262460166
# differential_evolution step 846: f(x)= 0.41257577262460166
# differential_evolution step 847: f(x)= 0.41257577262460166
# differential_evolution step 848: f(x)= 0.41257577262460166
# differential_evolution step 849: f(x)= 0.41257577262460166
# differential_evolution step 850: f(x)= 0.41257577262460166
# differential_evolution step 851: f(x)= 0.41257577262460166
# differential_evolution step 852: f(x)= 0.41244134699633184
# differential_evolution step 853: f(x)= 0.41244134699633184
# differential_evolution step 854: f(x)= 0.41244134699633184
# differential_evolution step 855: f(x)= 0.39845465989562706
# differential_evolution step 856: f(x)= 0.39845465989562706
# differential_evolution step 857: f(x)= 0.39845465989562706
# differential_evolution step 858: f(x)= 0.39845465989562706
# differential_evolution step 859: f(x)= 0.39845465989562706
# differential_evolution step 860: f(x)= 0.39845465989562706
# differential_evolution step 861: f(x)= 0.39596194522152506
# differential_evolution step 862: f(x)= 0.39596194522152506
# differential_evolution step 863: f(x)= 0.39596194522152506
# differential_evolution step 864: f(x)= 0.39596194522152506
# differential_evolution step 865: f(x)= 0.39596194522152506
# differential_evolution step 866: f(x)= 0.39596194522152506
# differential_evolution step 867: f(x)= 0.39596194522152506
# differential_evolution step 868: f(x)= 0.39596194522152506
# differential_evolution step 869: f(x)= 0.39596194522152506
# differential_evolution step 870: f(x)= 0.39596194522152506
# differential_evolution step 871: f(x)= 0.39596194522152506
# differential_evolution step 872: f(x)= 0.39596194522152506
# differential_evolution step 873: f(x)= 0.39596194522152506
# differential_evolution step 874: f(x)= 0.39596194522152506
# differential_evolution step 875: f(x)= 0.39596194522152506
# differential_evolution step 876: f(x)= 0.39596194522152506
# differential_evolution step 877: f(x)= 0.39596194522152506
# differential_evolution step 878: f(x)= 0.39596194522152506
# differential_evolution step 879: f(x)= 0.39596194522152506
# differential_evolution step 880: f(x)= 0.39596194522152506
# differential_evolution step 881: f(x)= 0.39596194522152506
# differential_evolution step 882: f(x)= 0.39596194522152506
# differential_evolution step 883: f(x)= 0.39596194522152506
# differential_evolution step 884: f(x)= 0.39596194522152506
# differential_evolution step 885: f(x)= 0.39596194522152506
# differential_evolution step 886: f(x)= 0.39596194522152506
# differential_evolution step 887: f(x)= 0.39596194522152506
# differential_evolution step 888: f(x)= 0.39596194522152506
# differential_evolution step 889: f(x)= 0.39596194522152506
# differential_evolution step 890: f(x)= 0.39596194522152506
# differential_evolution step 891: f(x)= 0.39596194522152506
# differential_evolution step 892: f(x)= 0.39596194522152506
# differential_evolution step 893: f(x)= 0.39596194522152506
# differential_evolution step 894: f(x)= 0.39596194522152506
# differential_evolution step 895: f(x)= 0.39596194522152506
# differential_evolution step 896: f(x)= 0.39596194522152506
# differential_evolution step 897: f(x)= 0.39588827799328213
# differential_evolution step 898: f(x)= 0.39588827799328213
# differential_evolution step 899: f(x)= 0.39588827799328213
# differential_evolution step 900: f(x)= 0.39588827799328213
# differential_evolution step 901: f(x)= 0.39588827799328213
# differential_evolution step 902: f(x)= 0.39588827799328213
# differential_evolution step 903: f(x)= 0.39588827799328213
# differential_evolution step 904: f(x)= 0.39588827799328213
# differential_evolution step 905: f(x)= 0.39588827799328213
# differential_evolution step 906: f(x)= 0.39588827799328213
# differential_evolution step 907: f(x)= 0.39588827799328213
# differential_evolution step 908: f(x)= 0.39588827799328213
# differential_evolution step 909: f(x)= 0.3922015142578959
# differential_evolution step 910: f(x)= 0.3922015142578959
# differential_evolution step 911: f(x)= 0.3922015142578959
# differential_evolution step 912: f(x)= 0.3922015142578959
# differential_evolution step 913: f(x)= 0.3922015142578959
# differential_evolution step 914: f(x)= 0.3922015142578959
# differential_evolution step 915: f(x)= 0.3922015142578959
# differential_evolution step 916: f(x)= 0.3922015142578959
# differential_evolution step 917: f(x)= 0.3922015142578959
# differential_evolution step 918: f(x)= 0.3922015142578959
# differential_evolution step 919: f(x)= 0.3922015142578959
# differential_evolution step 920: f(x)= 0.3922015142578959
# differential_evolution step 921: f(x)= 0.3922015142578959
# differential_evolution step 922: f(x)= 0.3922015142578959
# differential_evolution step 923: f(x)= 0.3922015142578959
# differential_evolution step 924: f(x)= 0.3922015142578959
# differential_evolution step 925: f(x)= 0.3922015142578959
# differential_evolution step 926: f(x)= 0.3922015142578959
# differential_evolution step 927: f(x)= 0.3922015142578959
# differential_evolution step 928: f(x)= 0.3922015142578959
# differential_evolution step 929: f(x)= 0.3922015142578959
# differential_evolution step 930: f(x)= 0.3922015142578959
# differential_evolution step 931: f(x)= 0.3922015142578959
# differential_evolution step 932: f(x)= 0.3922015142578959
# differential_evolution step 933: f(x)= 0.3922015142578959
# differential_evolution step 934: f(x)= 0.3922015142578959
# differential_evolution step 935: f(x)= 0.3922015142578959
# differential_evolution step 936: f(x)= 0.3922015142578959
# differential_evolution step 937: f(x)= 0.3922015142578959
# differential_evolution step 938: f(x)= 0.3922015142578959
# differential_evolution step 939: f(x)= 0.3922015142578959
# differential_evolution step 940: f(x)= 0.3922015142578959
# differential_evolution step 941: f(x)= 0.3922015142578959
# differential_evolution step 942: f(x)= 0.3922015142578959
# differential_evolution step 943: f(x)= 0.3922015142578959
# differential_evolution step 944: f(x)= 0.3922015142578959
# differential_evolution step 945: f(x)= 0.3922015142578959
# differential_evolution step 946: f(x)= 0.3922015142578959
# differential_evolution step 947: f(x)= 0.3922015142578959
# differential_evolution step 948: f(x)= 0.3922015142578959
# differential_evolution step 949: f(x)= 0.3922015142578959
# differential_evolution step 950: f(x)= 0.3922015142578959
# differential_evolution step 951: f(x)= 0.38556028559545397
# differential_evolution step 952: f(x)= 0.38556028559545397
# differential_evolution step 953: f(x)= 0.38556028559545397
# differential_evolution step 954: f(x)= 0.38556028559545397
# differential_evolution step 955: f(x)= 0.38457901123902666
# differential_evolution step 956: f(x)= 0.38457901123902666
# differential_evolution step 957: f(x)= 0.38457901123902666
# differential_evolution step 958: f(x)= 0.38457901123902666
# differential_evolution step 959: f(x)= 0.38457901123902666
# differential_evolution step 960: f(x)= 0.38457901123902666
# differential_evolution step 961: f(x)= 0.38457901123902666
# differential_evolution step 962: f(x)= 0.38457901123902666
# differential_evolution step 963: f(x)= 0.38457901123902666
# differential_evolution step 964: f(x)= 0.38457901123902666
# differential_evolution step 965: f(x)= 0.38457901123902666
# differential_evolution step 966: f(x)= 0.38457901123902666
# differential_evolution step 967: f(x)= 0.38457901123902666
# differential_evolution step 968: f(x)= 0.38457901123902666
# differential_evolution step 969: f(x)= 0.38457901123902666
# differential_evolution step 970: f(x)= 0.38457901123902666
# differential_evolution step 971: f(x)= 0.38457901123902666
# differential_evolution step 972: f(x)= 0.38457901123902666
# differential_evolution step 973: f(x)= 0.38457901123902666
# differential_evolution step 974: f(x)= 0.38457901123902666
# differential_evolution step 975: f(x)= 0.38457901123902666
# differential_evolution step 976: f(x)= 0.38457901123902666
# differential_evolution step 977: f(x)= 0.38457901123902666
# differential_evolution step 978: f(x)= 0.38457901123902666
# differential_evolution step 979: f(x)= 0.38457901123902666
# differential_evolution step 980: f(x)= 0.38457901123902666
# differential_evolution step 981: f(x)= 0.38457901123902666
# differential_evolution step 982: f(x)= 0.38457901123902666
# differential_evolution step 983: f(x)= 0.38457901123902666
# differential_evolution step 984: f(x)= 0.38457901123902666
# differential_evolution step 985: f(x)= 0.38457901123902666
# differential_evolution step 986: f(x)= 0.38457901123902666
# differential_evolution step 987: f(x)= 0.38457901123902666
# differential_evolution step 988: f(x)= 0.38457901123902666
# differential_evolution step 989: f(x)= 0.38457901123902666
# differential_evolution step 990: f(x)= 0.38457901123902666
# differential_evolution step 991: f(x)= 0.38457901123902666
# differential_evolution step 992: f(x)= 0.38457901123902666
# differential_evolution step 993: f(x)= 0.38457901123902666
# differential_evolution step 994: f(x)= 0.38457901123902666
# differential_evolution step 995: f(x)= 0.3694444478418197
# differential_evolution step 996: f(x)= 0.3694444478418197
# differential_evolution step 997: f(x)= 0.3694444478418197
# differential_evolution step 998: f(x)= 0.3694444478418197
# differential_evolution step 999: f(x)= 0.3694444478418197
# differential_evolution step 1000: f(x)= 0.3694444478418197
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution: [1.62613540e+00 1.52480966e+00 1.32971861e+00 2.88079787e+01
#  1.34146190e-01 6.46895035e+00 1.99766005e+00 5.70810073e+01
#  3.08141623e-01 5.58041710e+00 1.13008868e+00 7.75482607e+01
#  5.42173292e-01 1.38976933e+00 1.11626396e+00 8.32464918e+01
#  1.05579111e-01 8.22038525e+00 1.39244145e+00 1.47040578e+01
#  2.51059859e+00 3.11378221e-02 1.65545763e+00 6.97742339e+01
#  5.70019453e-02 4.43710599e+01 8.23845658e-01 6.83550121e+01]
# Chi quadro minimo: 0.3694444478418197

# %%
# Plots:
params_curve_7, covariance_7 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params7, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[6], red_chi[6] = save_params(params_curve_7, covariance_7, radial_profile_HA, radial_profile_error_HA, x_axes, 7, 
                                       line_name="Seven", output_prefix="fit")

aic[6] = AIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
bic[6] = BIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
print(aic[6], chi_quadr[6], bic[6], len(best_params7))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_7)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[20:24]),  linestyle='--', label='Sérsic 6')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[24:28]),  linestyle='--', label='Sérsic 7')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_7', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\2750497257.py:13: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4368, r_e=3.3959, n=2.3987, x_0=28.7915
# Sérsic 2: I_e=0.0812, r_e=11.0631, n=2.2946, x_0=57.0878
# Sérsic 3: I_e=0.3467, r_e=5.1313, n=1.0617, x_0=77.3630
# Sérsic 4: I_e=0.9452, r_e=1.3716, n=0.4719, x_0=83.1938
# Sérsic 5: I_e=0.1134, r_e=7.8341, n=1.4055, x_0=14.3670
# Sérsic 6: I_e=1.9034, r_e=0.0229, n=1.6442, x_0=69.7874
# Sérsic 7: I_e=0.0780, r_e=24.3189, n=0.4694, x_0=77.9387
# [4.29110053e-01 1.88710383e+00 2.15429625e+00 1.61864330e-02
#  4.67379957e-01 5.31992409e+01 4.95676328e+00 5.27618463e-02
#  3.26647089e-01 5.72893228e+00 6.88540242e-01 1.92490952e-01
#  7.65544557e-01 3.65788666e-01 7.06710125e-01 1.32086701e-01
#  4.25461689e-02 2.44589210e+00 2.78107386e-01 1.27962835e-01
#  8.34534935e+05 2.03719557e+03 3.26316883e+05 8.01222443e+01
#  2.05920724e-01 1.75265091e+01 1.84315170e+00 3.84247711e+01]
# 19.23683650347526
# 98.11007594009499 19.23683650347526 148.1816017111418 28
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24]) +
        sersic_1d(x_hr, *params[24:28]) +
        sersic_1d(x_hr, *params[28:32])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (28, 31),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 59),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (75, 79),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (80, 85),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 16),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 70),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params8 = result.x

print("Optimize parameters with differential_evolution:", best_params8)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 283951.22405295575
# differential_evolution step 2: f(x)= 180641.2040930393
# differential_evolution step 3: f(x)= 180641.2040930393
# differential_evolution step 4: f(x)= 72459.78476968578
# differential_evolution step 5: f(x)= 72459.78476968578
# differential_evolution step 6: f(x)= 72459.78476968578
# differential_evolution step 7: f(x)= 28034.610518755468
# differential_evolution step 8: f(x)= 28034.610518755468
# differential_evolution step 9: f(x)= 28034.610518755468
# differential_evolution step 10: f(x)= 28034.610518755468
# differential_evolution step 11: f(x)= 28034.610518755468
# differential_evolution step 12: f(x)= 16720.818005012174
# differential_evolution step 13: f(x)= 16720.818005012174
# differential_evolution step 14: f(x)= 11891.907785897896
# differential_evolution step 15: f(x)= 11891.907785897896
# differential_evolution step 16: f(x)= 11891.907785897896
# differential_evolution step 17: f(x)= 11891.907785897896
# differential_evolution step 18: f(x)= 11891.907785897896
# differential_evolution step 19: f(x)= 11891.907785897896
# differential_evolution step 20: f(x)= 11891.907785897896
# differential_evolution step 21: f(x)= 11488.098660498696
# differential_evolution step 22: f(x)= 11488.098660498696
# differential_evolution step 23: f(x)= 7400.401884137952
# differential_evolution step 24: f(x)= 7400.401884137952
# differential_evolution step 25: f(x)= 7400.401884137952
# differential_evolution step 26: f(x)= 7400.401884137952
# differential_evolution step 27: f(x)= 7400.401884137952
# differential_evolution step 28: f(x)= 7400.401884137952
# differential_evolution step 29: f(x)= 7400.401884137952
# differential_evolution step 30: f(x)= 7400.401884137952
# differential_evolution step 31: f(x)= 7400.401884137952
# differential_evolution step 32: f(x)= 7400.401884137952
# differential_evolution step 33: f(x)= 7400.401884137952
# differential_evolution step 34: f(x)= 7400.401884137952
# differential_evolution step 35: f(x)= 6136.650770299665
# differential_evolution step 36: f(x)= 6136.650770299665
# differential_evolution step 37: f(x)= 2251.9313754111736
# differential_evolution step 38: f(x)= 2251.9313754111736
# differential_evolution step 39: f(x)= 2251.9313754111736
# differential_evolution step 40: f(x)= 2251.9313754111736
# differential_evolution step 41: f(x)= 2251.9313754111736
# differential_evolution step 42: f(x)= 2251.9313754111736
# differential_evolution step 43: f(x)= 2251.9313754111736
# differential_evolution step 44: f(x)= 2251.9313754111736
# differential_evolution step 45: f(x)= 2251.9313754111736
# differential_evolution step 46: f(x)= 1537.473602329723
# differential_evolution step 47: f(x)= 1537.473602329723
# differential_evolution step 48: f(x)= 1537.473602329723
# differential_evolution step 49: f(x)= 1537.473602329723
# differential_evolution step 50: f(x)= 1537.473602329723
# differential_evolution step 51: f(x)= 1537.473602329723
# differential_evolution step 52: f(x)= 1537.473602329723
# differential_evolution step 53: f(x)= 1537.473602329723
# differential_evolution step 54: f(x)= 1537.473602329723
# differential_evolution step 55: f(x)= 660.4906786130059
# differential_evolution step 56: f(x)= 660.4906786130059
# differential_evolution step 57: f(x)= 660.4906786130059
# differential_evolution step 58: f(x)= 660.4906786130059
# differential_evolution step 59: f(x)= 660.4906786130059
# differential_evolution step 60: f(x)= 660.4906786130059
# differential_evolution step 61: f(x)= 660.4906786130059
# differential_evolution step 62: f(x)= 660.4906786130059
# differential_evolution step 63: f(x)= 660.4906786130059
# differential_evolution step 64: f(x)= 660.4906786130059
# differential_evolution step 65: f(x)= 660.4906786130059
# differential_evolution step 66: f(x)= 660.4906786130059
# differential_evolution step 67: f(x)= 660.4906786130059
# differential_evolution step 68: f(x)= 660.4906786130059
# differential_evolution step 69: f(x)= 426.28452839176606
# differential_evolution step 70: f(x)= 426.28452839176606
# differential_evolution step 71: f(x)= 426.28452839176606
# differential_evolution step 72: f(x)= 426.28452839176606
# differential_evolution step 73: f(x)= 291.0224117026692
# differential_evolution step 74: f(x)= 291.0224117026692
# differential_evolution step 75: f(x)= 291.0224117026692
# differential_evolution step 76: f(x)= 291.0224117026692
# differential_evolution step 77: f(x)= 291.0224117026692
# differential_evolution step 78: f(x)= 291.0224117026692
# differential_evolution step 79: f(x)= 212.69653581284553
# differential_evolution step 80: f(x)= 212.69653581284553
# differential_evolution step 81: f(x)= 212.69653581284553
# differential_evolution step 82: f(x)= 212.69653581284553
# differential_evolution step 83: f(x)= 212.69653581284553
# differential_evolution step 84: f(x)= 212.69653581284553
# differential_evolution step 85: f(x)= 212.69653581284553
# differential_evolution step 86: f(x)= 212.69653581284553
# differential_evolution step 87: f(x)= 212.69653581284553
# differential_evolution step 88: f(x)= 212.69653581284553
# differential_evolution step 89: f(x)= 212.69653581284553
# differential_evolution step 90: f(x)= 212.69653581284553
# differential_evolution step 91: f(x)= 212.69653581284553
# differential_evolution step 92: f(x)= 212.69653581284553
# differential_evolution step 93: f(x)= 212.69653581284553
# differential_evolution step 94: f(x)= 212.69653581284553
# differential_evolution step 95: f(x)= 212.69653581284553
# differential_evolution step 96: f(x)= 212.69653581284553
# differential_evolution step 97: f(x)= 212.69653581284553
# differential_evolution step 98: f(x)= 212.69653581284553
# differential_evolution step 99: f(x)= 212.69653581284553
# differential_evolution step 100: f(x)= 212.69653581284553
# differential_evolution step 101: f(x)= 212.69653581284553
# differential_evolution step 102: f(x)= 212.69653581284553
# differential_evolution step 103: f(x)= 212.69653581284553
# differential_evolution step 104: f(x)= 212.69653581284553
# differential_evolution step 105: f(x)= 212.69653581284553
# differential_evolution step 106: f(x)= 212.69653581284553
# differential_evolution step 107: f(x)= 212.69653581284553
# differential_evolution step 108: f(x)= 212.69653581284553
# differential_evolution step 109: f(x)= 212.69653581284553
# differential_evolution step 110: f(x)= 212.69653581284553
# differential_evolution step 111: f(x)= 212.69653581284553
# differential_evolution step 112: f(x)= 212.69653581284553
# differential_evolution step 113: f(x)= 212.69653581284553
# differential_evolution step 114: f(x)= 212.69653581284553
# differential_evolution step 115: f(x)= 212.69653581284553
# differential_evolution step 116: f(x)= 212.69653581284553
# differential_evolution step 117: f(x)= 212.69653581284553
# differential_evolution step 118: f(x)= 212.69653581284553
# differential_evolution step 119: f(x)= 212.69653581284553
# differential_evolution step 120: f(x)= 212.69653581284553
# differential_evolution step 121: f(x)= 212.69653581284553
# differential_evolution step 122: f(x)= 212.69653581284553
# differential_evolution step 123: f(x)= 117.36084929821655
# differential_evolution step 124: f(x)= 117.36084929821655
# differential_evolution step 125: f(x)= 117.36084929821655
# differential_evolution step 126: f(x)= 108.60288180810197
# differential_evolution step 127: f(x)= 108.60288180810197
# differential_evolution step 128: f(x)= 108.60288180810197
# differential_evolution step 129: f(x)= 108.60288180810197
# differential_evolution step 130: f(x)= 108.60288180810197
# differential_evolution step 131: f(x)= 108.60288180810197
# differential_evolution step 132: f(x)= 108.60288180810197
# differential_evolution step 133: f(x)= 108.60288180810197
# differential_evolution step 134: f(x)= 108.60288180810197
# differential_evolution step 135: f(x)= 108.60288180810197
# differential_evolution step 136: f(x)= 108.60288180810197
# differential_evolution step 137: f(x)= 108.60288180810197
# differential_evolution step 138: f(x)= 108.60288180810197
# differential_evolution step 139: f(x)= 108.60288180810197
# differential_evolution step 140: f(x)= 108.60288180810197
# differential_evolution step 141: f(x)= 108.60288180810197
# differential_evolution step 142: f(x)= 108.60288180810197
# differential_evolution step 143: f(x)= 108.60288180810197
# differential_evolution step 144: f(x)= 108.60288180810197
# differential_evolution step 145: f(x)= 108.60288180810197
# differential_evolution step 146: f(x)= 108.60288180810197
# differential_evolution step 147: f(x)= 108.60288180810197
# differential_evolution step 148: f(x)= 108.60288180810197
# differential_evolution step 149: f(x)= 108.60288180810197
# differential_evolution step 150: f(x)= 108.60288180810197
# differential_evolution step 151: f(x)= 108.60288180810197
# differential_evolution step 152: f(x)= 108.60288180810197
# differential_evolution step 153: f(x)= 108.60288180810197
# differential_evolution step 154: f(x)= 108.60288180810197
# differential_evolution step 155: f(x)= 69.52696408474827
# differential_evolution step 156: f(x)= 69.52696408474827
# differential_evolution step 157: f(x)= 69.52696408474827
# differential_evolution step 158: f(x)= 69.52696408474827
# differential_evolution step 159: f(x)= 69.52696408474827
# differential_evolution step 160: f(x)= 69.52696408474827
# differential_evolution step 161: f(x)= 69.52696408474827
# differential_evolution step 162: f(x)= 69.52696408474827
# differential_evolution step 163: f(x)= 69.52696408474827
# differential_evolution step 164: f(x)= 69.52696408474827
# differential_evolution step 165: f(x)= 69.52696408474827
# differential_evolution step 166: f(x)= 69.52696408474827
# differential_evolution step 167: f(x)= 69.52696408474827
# differential_evolution step 168: f(x)= 69.52696408474827
# differential_evolution step 169: f(x)= 69.52696408474827
# differential_evolution step 170: f(x)= 65.30134737514369
# differential_evolution step 171: f(x)= 65.30134737514369
# differential_evolution step 172: f(x)= 65.30134737514369
# differential_evolution step 173: f(x)= 65.30134737514369
# differential_evolution step 174: f(x)= 63.1951226415785
# differential_evolution step 175: f(x)= 63.1951226415785
# differential_evolution step 176: f(x)= 63.1951226415785
# differential_evolution step 177: f(x)= 63.1951226415785
# differential_evolution step 178: f(x)= 63.1951226415785
# differential_evolution step 179: f(x)= 63.1951226415785
# differential_evolution step 180: f(x)= 63.1951226415785
# differential_evolution step 181: f(x)= 63.1951226415785
# differential_evolution step 182: f(x)= 63.1951226415785
# differential_evolution step 183: f(x)= 63.1951226415785
# differential_evolution step 184: f(x)= 54.57951682270685
# differential_evolution step 185: f(x)= 54.57951682270685
# differential_evolution step 186: f(x)= 54.57951682270685
# differential_evolution step 187: f(x)= 54.57951682270685
# differential_evolution step 188: f(x)= 54.57951682270685
# differential_evolution step 189: f(x)= 54.57951682270685
# differential_evolution step 190: f(x)= 54.57951682270685
# differential_evolution step 191: f(x)= 54.57951682270685
# differential_evolution step 192: f(x)= 54.57951682270685
# differential_evolution step 193: f(x)= 54.57951682270685
# differential_evolution step 194: f(x)= 54.57951682270685
# differential_evolution step 195: f(x)= 54.57951682270685
# differential_evolution step 196: f(x)= 54.57951682270685
# differential_evolution step 197: f(x)= 54.57951682270685
# differential_evolution step 198: f(x)= 54.57951682270685
# differential_evolution step 199: f(x)= 54.57951682270685
# differential_evolution step 200: f(x)= 54.57951682270685
# differential_evolution step 201: f(x)= 54.57951682270685
# differential_evolution step 202: f(x)= 54.57951682270685
# differential_evolution step 203: f(x)= 54.57951682270685
# differential_evolution step 204: f(x)= 54.57951682270685
# differential_evolution step 205: f(x)= 54.57951682270685
# differential_evolution step 206: f(x)= 54.57951682270685
# differential_evolution step 207: f(x)= 54.57951682270685
# differential_evolution step 208: f(x)= 54.57951682270685
# differential_evolution step 209: f(x)= 54.57951682270685
# differential_evolution step 210: f(x)= 54.57951682270685
# differential_evolution step 211: f(x)= 54.57951682270685
# differential_evolution step 212: f(x)= 54.57951682270685
# differential_evolution step 213: f(x)= 54.57951682270685
# differential_evolution step 214: f(x)= 54.57951682270685
# differential_evolution step 215: f(x)= 54.57951682270685
# differential_evolution step 216: f(x)= 54.57951682270685
# differential_evolution step 217: f(x)= 54.57951682270685
# differential_evolution step 218: f(x)= 50.283596690173674
# differential_evolution step 219: f(x)= 50.283596690173674
# differential_evolution step 220: f(x)= 50.283596690173674
# differential_evolution step 221: f(x)= 50.283596690173674
# differential_evolution step 222: f(x)= 50.283596690173674
# differential_evolution step 223: f(x)= 50.283596690173674
# differential_evolution step 224: f(x)= 50.283596690173674
# differential_evolution step 225: f(x)= 50.283596690173674
# differential_evolution step 226: f(x)= 50.283596690173674
# differential_evolution step 227: f(x)= 50.283596690173674
# differential_evolution step 228: f(x)= 50.283596690173674
# differential_evolution step 229: f(x)= 48.11935873664185
# differential_evolution step 230: f(x)= 48.11935873664185
# differential_evolution step 231: f(x)= 48.11935873664185
# differential_evolution step 232: f(x)= 48.11935873664185
# differential_evolution step 233: f(x)= 48.11935873664185
# differential_evolution step 234: f(x)= 48.11935873664185
# differential_evolution step 235: f(x)= 32.651231275730076
# differential_evolution step 236: f(x)= 32.651231275730076
# differential_evolution step 237: f(x)= 32.651231275730076
# differential_evolution step 238: f(x)= 32.651231275730076
# differential_evolution step 239: f(x)= 25.162596050543307
# differential_evolution step 240: f(x)= 25.162596050543307
# differential_evolution step 241: f(x)= 25.162596050543307
# differential_evolution step 242: f(x)= 25.162596050543307
# differential_evolution step 243: f(x)= 25.162596050543307
# differential_evolution step 244: f(x)= 25.162596050543307
# differential_evolution step 245: f(x)= 25.162596050543307
# differential_evolution step 246: f(x)= 25.162596050543307
# differential_evolution step 247: f(x)= 25.162596050543307
# differential_evolution step 248: f(x)= 25.162596050543307
# differential_evolution step 249: f(x)= 25.162596050543307
# differential_evolution step 250: f(x)= 25.162596050543307
# differential_evolution step 251: f(x)= 25.162596050543307
# differential_evolution step 252: f(x)= 25.162596050543307
# differential_evolution step 253: f(x)= 25.162596050543307
# differential_evolution step 254: f(x)= 25.162596050543307
# differential_evolution step 255: f(x)= 25.162596050543307
# differential_evolution step 256: f(x)= 25.162596050543307
# differential_evolution step 257: f(x)= 25.162596050543307
# differential_evolution step 258: f(x)= 25.162596050543307
# differential_evolution step 259: f(x)= 25.162596050543307
# differential_evolution step 260: f(x)= 25.162596050543307
# differential_evolution step 261: f(x)= 22.526053139540654
# differential_evolution step 262: f(x)= 22.526053139540654
# differential_evolution step 263: f(x)= 22.526053139540654
# differential_evolution step 264: f(x)= 22.526053139540654
# differential_evolution step 265: f(x)= 22.526053139540654
# differential_evolution step 266: f(x)= 19.659084254566707
# differential_evolution step 267: f(x)= 19.659084254566707
# differential_evolution step 268: f(x)= 19.659084254566707
# differential_evolution step 269: f(x)= 19.659084254566707
# differential_evolution step 270: f(x)= 19.659084254566707
# differential_evolution step 271: f(x)= 19.659084254566707
# differential_evolution step 272: f(x)= 13.414879832448086
# differential_evolution step 273: f(x)= 13.414879832448086
# differential_evolution step 274: f(x)= 13.414879832448086
# differential_evolution step 275: f(x)= 13.414879832448086
# differential_evolution step 276: f(x)= 13.414879832448086
# differential_evolution step 277: f(x)= 13.414879832448086
# differential_evolution step 278: f(x)= 13.414879832448086
# differential_evolution step 279: f(x)= 13.414879832448086
# differential_evolution step 280: f(x)= 13.414879832448086
# differential_evolution step 281: f(x)= 13.414879832448086
# differential_evolution step 282: f(x)= 13.414879832448086
# differential_evolution step 283: f(x)= 13.414879832448086
# differential_evolution step 284: f(x)= 13.414879832448086
# differential_evolution step 285: f(x)= 13.414879832448086
# differential_evolution step 286: f(x)= 13.414879832448086
# differential_evolution step 287: f(x)= 13.414879832448086
# differential_evolution step 288: f(x)= 13.414879832448086
# differential_evolution step 289: f(x)= 13.414879832448086
# differential_evolution step 290: f(x)= 13.414879832448086
# differential_evolution step 291: f(x)= 13.414879832448086
# differential_evolution step 292: f(x)= 13.414879832448086
# differential_evolution step 293: f(x)= 13.414879832448086
# differential_evolution step 294: f(x)= 13.414879832448086
# differential_evolution step 295: f(x)= 12.079811961971071
# differential_evolution step 296: f(x)= 12.079811961971071
# differential_evolution step 297: f(x)= 12.079811961971071
# differential_evolution step 298: f(x)= 12.079811961971071
# differential_evolution step 299: f(x)= 12.079811961971071
# differential_evolution step 300: f(x)= 11.431135549149413
# differential_evolution step 301: f(x)= 11.431135549149413
# differential_evolution step 302: f(x)= 11.431135549149413
# differential_evolution step 303: f(x)= 11.431135549149413
# differential_evolution step 304: f(x)= 11.431135549149413
# differential_evolution step 305: f(x)= 11.431135549149413
# differential_evolution step 306: f(x)= 11.431135549149413
# differential_evolution step 307: f(x)= 11.431135549149413
# differential_evolution step 308: f(x)= 11.431135549149413
# differential_evolution step 309: f(x)= 11.431135549149413
# differential_evolution step 310: f(x)= 11.431135549149413
# differential_evolution step 311: f(x)= 11.431135549149413
# differential_evolution step 312: f(x)= 11.431135549149413
# differential_evolution step 313: f(x)= 11.431135549149413
# differential_evolution step 314: f(x)= 11.431135549149413
# differential_evolution step 315: f(x)= 11.431135549149413
# differential_evolution step 316: f(x)= 11.431135549149413
# differential_evolution step 317: f(x)= 11.431135549149413
# differential_evolution step 318: f(x)= 11.431135549149413
# differential_evolution step 319: f(x)= 11.431135549149413
# differential_evolution step 320: f(x)= 11.431135549149413
# differential_evolution step 321: f(x)= 11.431135549149413
# differential_evolution step 322: f(x)= 11.431135549149413
# differential_evolution step 323: f(x)= 11.431135549149413
# differential_evolution step 324: f(x)= 11.431135549149413
# differential_evolution step 325: f(x)= 11.431135549149413
# differential_evolution step 326: f(x)= 11.431135549149413
# differential_evolution step 327: f(x)= 11.431135549149413
# differential_evolution step 328: f(x)= 11.431135549149413
# differential_evolution step 329: f(x)= 11.431135549149413
# differential_evolution step 330: f(x)= 9.641544563726544
# differential_evolution step 331: f(x)= 9.641544563726544
# differential_evolution step 332: f(x)= 9.641544563726544
# differential_evolution step 333: f(x)= 9.641544563726544
# differential_evolution step 334: f(x)= 9.641544563726544
# differential_evolution step 335: f(x)= 9.641544563726544
# differential_evolution step 336: f(x)= 9.641544563726544
# differential_evolution step 337: f(x)= 9.641544563726544
# differential_evolution step 338: f(x)= 9.641544563726544
# differential_evolution step 339: f(x)= 9.641544563726544
# differential_evolution step 340: f(x)= 9.641544563726544
# differential_evolution step 341: f(x)= 9.641544563726544
# differential_evolution step 342: f(x)= 9.641544563726544
# differential_evolution step 343: f(x)= 9.641544563726544
# differential_evolution step 344: f(x)= 9.641544563726544
# differential_evolution step 345: f(x)= 9.641544563726544
# differential_evolution step 346: f(x)= 9.641544563726544
# differential_evolution step 347: f(x)= 9.641544563726544
# differential_evolution step 348: f(x)= 9.641544563726544
# differential_evolution step 349: f(x)= 9.641544563726544
# differential_evolution step 350: f(x)= 9.641544563726544
# differential_evolution step 351: f(x)= 9.641544563726544
# differential_evolution step 352: f(x)= 9.641544563726544
# differential_evolution step 353: f(x)= 9.641544563726544
# differential_evolution step 354: f(x)= 8.925920643098454
# differential_evolution step 355: f(x)= 8.925920643098454
# differential_evolution step 356: f(x)= 8.925920643098454
# differential_evolution step 357: f(x)= 8.925920643098454
# differential_evolution step 358: f(x)= 8.925920643098454
# differential_evolution step 359: f(x)= 8.925920643098454
# differential_evolution step 360: f(x)= 8.925920643098454
# differential_evolution step 361: f(x)= 8.925920643098454
# differential_evolution step 362: f(x)= 8.925920643098454
# differential_evolution step 363: f(x)= 8.925920643098454
# differential_evolution step 364: f(x)= 8.925920643098454
# differential_evolution step 365: f(x)= 8.846528867620648
# differential_evolution step 366: f(x)= 8.846528867620648
# differential_evolution step 367: f(x)= 8.846528867620648
# differential_evolution step 368: f(x)= 8.846528867620648
# differential_evolution step 369: f(x)= 8.846528867620648
# differential_evolution step 370: f(x)= 8.846528867620648
# differential_evolution step 371: f(x)= 8.846528867620648
# differential_evolution step 372: f(x)= 8.846528867620648
# differential_evolution step 373: f(x)= 8.846528867620648
# differential_evolution step 374: f(x)= 8.846528867620648
# differential_evolution step 375: f(x)= 4.885259057337918
# differential_evolution step 376: f(x)= 4.885259057337918
# differential_evolution step 377: f(x)= 4.885259057337918
# differential_evolution step 378: f(x)= 4.885259057337918
# differential_evolution step 379: f(x)= 4.885259057337918
# differential_evolution step 380: f(x)= 4.885259057337918
# differential_evolution step 381: f(x)= 4.885259057337918
# differential_evolution step 382: f(x)= 4.885259057337918
# differential_evolution step 383: f(x)= 4.885259057337918
# differential_evolution step 384: f(x)= 4.885259057337918
# differential_evolution step 385: f(x)= 4.885259057337918
# differential_evolution step 386: f(x)= 4.885259057337918
# differential_evolution step 387: f(x)= 4.885259057337918
# differential_evolution step 388: f(x)= 4.885259057337918
# differential_evolution step 389: f(x)= 4.885259057337918
# differential_evolution step 390: f(x)= 4.885259057337918
# differential_evolution step 391: f(x)= 4.885259057337918
# differential_evolution step 392: f(x)= 4.885259057337918
# differential_evolution step 393: f(x)= 4.885259057337918
# differential_evolution step 394: f(x)= 4.885259057337918
# differential_evolution step 395: f(x)= 4.885259057337918
# differential_evolution step 396: f(x)= 4.885259057337918
# differential_evolution step 397: f(x)= 4.885259057337918
# differential_evolution step 398: f(x)= 4.885259057337918
# differential_evolution step 399: f(x)= 4.885259057337918
# differential_evolution step 400: f(x)= 4.313454700906791
# differential_evolution step 401: f(x)= 4.313454700906791
# differential_evolution step 402: f(x)= 4.313454700906791
# differential_evolution step 403: f(x)= 4.313454700906791
# differential_evolution step 404: f(x)= 4.313454700906791
# differential_evolution step 405: f(x)= 4.313454700906791
# differential_evolution step 406: f(x)= 4.313454700906791
# differential_evolution step 407: f(x)= 4.313454700906791
# differential_evolution step 408: f(x)= 4.313454700906791
# differential_evolution step 409: f(x)= 4.313454700906791
# differential_evolution step 410: f(x)= 4.313454700906791
# differential_evolution step 411: f(x)= 4.313454700906791
# differential_evolution step 412: f(x)= 4.313454700906791
# differential_evolution step 413: f(x)= 4.313454700906791
# differential_evolution step 414: f(x)= 3.3798652141329466
# differential_evolution step 415: f(x)= 3.3798652141329466
# differential_evolution step 416: f(x)= 3.3798652141329466
# differential_evolution step 417: f(x)= 3.3798652141329466
# differential_evolution step 418: f(x)= 3.3798652141329466
# differential_evolution step 419: f(x)= 3.3798652141329466
# differential_evolution step 420: f(x)= 3.3798652141329466
# differential_evolution step 421: f(x)= 3.3798652141329466
# differential_evolution step 422: f(x)= 3.3798652141329466
# differential_evolution step 423: f(x)= 3.3798652141329466
# differential_evolution step 424: f(x)= 3.3798652141329466
# differential_evolution step 425: f(x)= 3.3798652141329466
# differential_evolution step 426: f(x)= 3.3798652141329466
# differential_evolution step 427: f(x)= 3.3798652141329466
# differential_evolution step 428: f(x)= 3.3762064866603527
# differential_evolution step 429: f(x)= 3.3762064866603527
# differential_evolution step 430: f(x)= 3.3762064866603527
# differential_evolution step 431: f(x)= 3.3762064866603527
# differential_evolution step 432: f(x)= 3.3762064866603527
# differential_evolution step 433: f(x)= 2.5308772179917116
# differential_evolution step 434: f(x)= 2.5308772179917116
# differential_evolution step 435: f(x)= 2.5308772179917116
# differential_evolution step 436: f(x)= 2.5308772179917116
# differential_evolution step 437: f(x)= 2.5308772179917116
# differential_evolution step 438: f(x)= 2.5308772179917116
# differential_evolution step 439: f(x)= 2.5308772179917116
# differential_evolution step 440: f(x)= 2.5308772179917116
# differential_evolution step 441: f(x)= 2.5308772179917116
# differential_evolution step 442: f(x)= 2.5308772179917116
# differential_evolution step 443: f(x)= 2.5308772179917116
# differential_evolution step 444: f(x)= 2.5308772179917116
# differential_evolution step 445: f(x)= 2.5308772179917116
# differential_evolution step 446: f(x)= 2.5308772179917116
# differential_evolution step 447: f(x)= 2.5308772179917116
# differential_evolution step 448: f(x)= 2.5308772179917116
# differential_evolution step 449: f(x)= 2.5308772179917116
# differential_evolution step 450: f(x)= 2.5308772179917116
# differential_evolution step 451: f(x)= 2.5308772179917116
# differential_evolution step 452: f(x)= 2.5308772179917116
# differential_evolution step 453: f(x)= 2.5308772179917116
# differential_evolution step 454: f(x)= 2.5308772179917116
# differential_evolution step 455: f(x)= 2.5308772179917116
# differential_evolution step 456: f(x)= 2.5308772179917116
# differential_evolution step 457: f(x)= 2.5308772179917116
# differential_evolution step 458: f(x)= 2.5308772179917116
# differential_evolution step 459: f(x)= 2.5308772179917116
# differential_evolution step 460: f(x)= 2.5308772179917116
# differential_evolution step 461: f(x)= 2.5308772179917116
# differential_evolution step 462: f(x)= 2.5308772179917116
# differential_evolution step 463: f(x)= 2.5308772179917116
# differential_evolution step 464: f(x)= 2.5308772179917116
# differential_evolution step 465: f(x)= 2.5308772179917116
# differential_evolution step 466: f(x)= 2.5308772179917116
# differential_evolution step 467: f(x)= 2.5308772179917116
# differential_evolution step 468: f(x)= 2.5308772179917116
# differential_evolution step 469: f(x)= 2.5308772179917116
# differential_evolution step 470: f(x)= 2.5308772179917116
# differential_evolution step 471: f(x)= 2.5308772179917116
# differential_evolution step 472: f(x)= 2.5308772179917116
# differential_evolution step 473: f(x)= 2.5308772179917116
# differential_evolution step 474: f(x)= 2.5308772179917116
# differential_evolution step 475: f(x)= 2.5308772179917116
# differential_evolution step 476: f(x)= 2.257837207346941
# differential_evolution step 477: f(x)= 2.257837207346941
# differential_evolution step 478: f(x)= 2.257837207346941
# differential_evolution step 479: f(x)= 2.257837207346941
# differential_evolution step 480: f(x)= 2.257837207346941
# differential_evolution step 481: f(x)= 1.9980228985419315
# differential_evolution step 482: f(x)= 1.9980228985419315
# differential_evolution step 483: f(x)= 1.9980228985419315
# differential_evolution step 484: f(x)= 1.9980228985419315
# differential_evolution step 485: f(x)= 1.9980228985419315
# differential_evolution step 486: f(x)= 1.9980228985419315
# differential_evolution step 487: f(x)= 1.9980228985419315
# differential_evolution step 488: f(x)= 1.9980228985419315
# differential_evolution step 489: f(x)= 1.9980228985419315
# differential_evolution step 490: f(x)= 1.9980228985419315
# differential_evolution step 491: f(x)= 1.9980228985419315
# differential_evolution step 492: f(x)= 1.9980228985419315
# differential_evolution step 493: f(x)= 1.9980228985419315
# differential_evolution step 494: f(x)= 1.9980228985419315
# differential_evolution step 495: f(x)= 1.9980228985419315
# differential_evolution step 496: f(x)= 1.9980228985419315
# differential_evolution step 497: f(x)= 1.9980228985419315
# differential_evolution step 498: f(x)= 1.9980228985419315
# differential_evolution step 499: f(x)= 1.9980228985419315
# differential_evolution step 500: f(x)= 1.8344711801388514
# differential_evolution step 501: f(x)= 1.8344711801388514
# differential_evolution step 502: f(x)= 1.8344711801388514
# differential_evolution step 503: f(x)= 1.8344711801388514
# differential_evolution step 504: f(x)= 1.8344711801388514
# differential_evolution step 505: f(x)= 1.8344711801388514
# differential_evolution step 506: f(x)= 1.8344711801388514
# differential_evolution step 507: f(x)= 1.8344711801388514
# differential_evolution step 508: f(x)= 1.8344711801388514
# differential_evolution step 509: f(x)= 1.8344711801388514
# differential_evolution step 510: f(x)= 1.8344711801388514
# differential_evolution step 511: f(x)= 1.3762699592413852
# differential_evolution step 512: f(x)= 1.3762699592413852
# differential_evolution step 513: f(x)= 1.3762699592413852
# differential_evolution step 514: f(x)= 1.3762699592413852
# differential_evolution step 515: f(x)= 1.3762699592413852
# differential_evolution step 516: f(x)= 1.3762699592413852
# differential_evolution step 517: f(x)= 1.3762699592413852
# differential_evolution step 518: f(x)= 1.3762699592413852
# differential_evolution step 519: f(x)= 1.3762699592413852
# differential_evolution step 520: f(x)= 1.3762699592413852
# differential_evolution step 521: f(x)= 1.3762699592413852
# differential_evolution step 522: f(x)= 1.3762699592413852
# differential_evolution step 523: f(x)= 1.3762699592413852
# differential_evolution step 524: f(x)= 1.3762699592413852
# differential_evolution step 525: f(x)= 1.3762699592413852
# differential_evolution step 526: f(x)= 1.3762699592413852
# differential_evolution step 527: f(x)= 1.3762699592413852
# differential_evolution step 528: f(x)= 1.3762699592413852
# differential_evolution step 529: f(x)= 1.3762699592413852
# differential_evolution step 530: f(x)= 1.3762699592413852
# differential_evolution step 531: f(x)= 1.3762699592413852
# differential_evolution step 532: f(x)= 1.3762699592413852
# differential_evolution step 533: f(x)= 1.3394473442983075
# differential_evolution step 534: f(x)= 1.3394473442983075
# differential_evolution step 535: f(x)= 1.3394473442983075
# differential_evolution step 536: f(x)= 1.2817428047163661
# differential_evolution step 537: f(x)= 1.2817428047163661
# differential_evolution step 538: f(x)= 1.2817428047163661
# differential_evolution step 539: f(x)= 1.2817428047163661
# differential_evolution step 540: f(x)= 1.2817428047163661
# differential_evolution step 541: f(x)= 1.2817428047163661
# differential_evolution step 542: f(x)= 1.2817428047163661
# differential_evolution step 543: f(x)= 1.2817428047163661
# differential_evolution step 544: f(x)= 1.2817428047163661
# differential_evolution step 545: f(x)= 1.2817428047163661
# differential_evolution step 546: f(x)= 1.2817428047163661
# differential_evolution step 547: f(x)= 1.2817428047163661
# differential_evolution step 548: f(x)= 1.2817428047163661
# differential_evolution step 549: f(x)= 1.2817428047163661
# differential_evolution step 550: f(x)= 1.2817428047163661
# differential_evolution step 551: f(x)= 1.2817428047163661
# differential_evolution step 552: f(x)= 1.2817428047163661
# differential_evolution step 553: f(x)= 1.2817428047163661
# differential_evolution step 554: f(x)= 1.2817428047163661
# differential_evolution step 555: f(x)= 1.2817428047163661
# differential_evolution step 556: f(x)= 1.2817428047163661
# differential_evolution step 557: f(x)= 1.2817428047163661
# differential_evolution step 558: f(x)= 1.071417518106452
# differential_evolution step 559: f(x)= 1.0701666638381682
# differential_evolution step 560: f(x)= 1.0701666638381682
# differential_evolution step 561: f(x)= 1.0701666638381682
# differential_evolution step 562: f(x)= 1.0701666638381682
# differential_evolution step 563: f(x)= 1.0701666638381682
# differential_evolution step 564: f(x)= 1.0701666638381682
# differential_evolution step 565: f(x)= 1.0701666638381682
# differential_evolution step 566: f(x)= 1.0701666638381682
# differential_evolution step 567: f(x)= 1.0022865716128435
# differential_evolution step 568: f(x)= 1.0022865716128435
# differential_evolution step 569: f(x)= 1.0022865716128435
# differential_evolution step 570: f(x)= 1.0022865716128435
# differential_evolution step 571: f(x)= 1.0022865716128435
# differential_evolution step 572: f(x)= 1.0022865716128435
# differential_evolution step 573: f(x)= 1.0022865716128435
# differential_evolution step 574: f(x)= 1.0022865716128435
# differential_evolution step 575: f(x)= 1.0022865716128435
# differential_evolution step 576: f(x)= 1.0022865716128435
# differential_evolution step 577: f(x)= 1.0022865716128435
# differential_evolution step 578: f(x)= 1.0022865716128435
# differential_evolution step 579: f(x)= 0.8951787573928829
# differential_evolution step 580: f(x)= 0.8951787573928829
# differential_evolution step 581: f(x)= 0.8951787573928829
# differential_evolution step 582: f(x)= 0.8951787573928829
# differential_evolution step 583: f(x)= 0.8951787573928829
# differential_evolution step 584: f(x)= 0.8951787573928829
# differential_evolution step 585: f(x)= 0.8951787573928829
# differential_evolution step 586: f(x)= 0.8951787573928829
# differential_evolution step 587: f(x)= 0.8951787573928829
# differential_evolution step 588: f(x)= 0.8951787573928829
# differential_evolution step 589: f(x)= 0.8951787573928829
# differential_evolution step 590: f(x)= 0.8951787573928829
# differential_evolution step 591: f(x)= 0.8501440041635411
# differential_evolution step 592: f(x)= 0.8501440041635411
# differential_evolution step 593: f(x)= 0.8501440041635411
# differential_evolution step 594: f(x)= 0.8501440041635411
# differential_evolution step 595: f(x)= 0.8501440041635411
# differential_evolution step 596: f(x)= 0.8501440041635411
# differential_evolution step 597: f(x)= 0.8501440041635411
# differential_evolution step 598: f(x)= 0.8501440041635411
# differential_evolution step 599: f(x)= 0.8501440041635411
# differential_evolution step 600: f(x)= 0.8501440041635411
# differential_evolution step 601: f(x)= 0.8501440041635411
# differential_evolution step 602: f(x)= 0.8501440041635411
# differential_evolution step 603: f(x)= 0.8501440041635411
# differential_evolution step 604: f(x)= 0.7668102270067014
# differential_evolution step 605: f(x)= 0.7668102270067014
# differential_evolution step 606: f(x)= 0.7668102270067014
# differential_evolution step 607: f(x)= 0.7668102270067014
# differential_evolution step 608: f(x)= 0.7668102270067014
# differential_evolution step 609: f(x)= 0.7668102270067014
# differential_evolution step 610: f(x)= 0.7668102270067014
# differential_evolution step 611: f(x)= 0.7668102270067014
# differential_evolution step 612: f(x)= 0.7668102270067014
# differential_evolution step 613: f(x)= 0.7668102270067014
# differential_evolution step 614: f(x)= 0.7668102270067014
# differential_evolution step 615: f(x)= 0.7668102270067014
# differential_evolution step 616: f(x)= 0.7668102270067014
# differential_evolution step 617: f(x)= 0.7668102270067014
# differential_evolution step 618: f(x)= 0.7668102270067014
# differential_evolution step 619: f(x)= 0.7668102270067014
# differential_evolution step 620: f(x)= 0.7668102270067014
# differential_evolution step 621: f(x)= 0.7668102270067014
# differential_evolution step 622: f(x)= 0.7668102270067014
# differential_evolution step 623: f(x)= 0.7668102270067014
# differential_evolution step 624: f(x)= 0.7668102270067014
# differential_evolution step 625: f(x)= 0.7668102270067014
# differential_evolution step 626: f(x)= 0.7668102270067014
# differential_evolution step 627: f(x)= 0.7668102270067014
# differential_evolution step 628: f(x)= 0.7668102270067014
# differential_evolution step 629: f(x)= 0.7668102270067014
# differential_evolution step 630: f(x)= 0.7668102270067014
# differential_evolution step 631: f(x)= 0.7668102270067014
# differential_evolution step 632: f(x)= 0.7668102270067014
# differential_evolution step 633: f(x)= 0.7531215901517737
# differential_evolution step 634: f(x)= 0.7531215901517737
# differential_evolution step 635: f(x)= 0.7531215901517737
# differential_evolution step 636: f(x)= 0.7531215901517737
# differential_evolution step 637: f(x)= 0.7531215901517737
# differential_evolution step 638: f(x)= 0.7531215901517737
# differential_evolution step 639: f(x)= 0.7531215901517737
# differential_evolution step 640: f(x)= 0.7531215901517737
# differential_evolution step 641: f(x)= 0.7073451709435117
# differential_evolution step 642: f(x)= 0.7073451709435117
# differential_evolution step 643: f(x)= 0.7073451709435117
# differential_evolution step 644: f(x)= 0.7073451709435117
# differential_evolution step 645: f(x)= 0.7073451709435117
# differential_evolution step 646: f(x)= 0.7073451709435117
# differential_evolution step 647: f(x)= 0.7073451709435117
# differential_evolution step 648: f(x)= 0.7073451709435117
# differential_evolution step 649: f(x)= 0.7073451709435117
# differential_evolution step 650: f(x)= 0.7073451709435117
# differential_evolution step 651: f(x)= 0.7073451709435117
# differential_evolution step 652: f(x)= 0.7073451709435117
# differential_evolution step 653: f(x)= 0.7073451709435117
# differential_evolution step 654: f(x)= 0.7073451709435117
# differential_evolution step 655: f(x)= 0.7073451709435117
# differential_evolution step 656: f(x)= 0.7073451709435117
# differential_evolution step 657: f(x)= 0.7073451709435117
# differential_evolution step 658: f(x)= 0.7073451709435117
# differential_evolution step 659: f(x)= 0.7073451709435117
# differential_evolution step 660: f(x)= 0.7073451709435117
# differential_evolution step 661: f(x)= 0.6876309516783682
# differential_evolution step 662: f(x)= 0.6876309516783682
# differential_evolution step 663: f(x)= 0.6876309516783682
# differential_evolution step 664: f(x)= 0.6876309516783682
# differential_evolution step 665: f(x)= 0.6876309516783682
# differential_evolution step 666: f(x)= 0.6876309516783682
# differential_evolution step 667: f(x)= 0.6876309516783682
# differential_evolution step 668: f(x)= 0.6876309516783682
# differential_evolution step 669: f(x)= 0.6876309516783682
# differential_evolution step 670: f(x)= 0.6876309516783682
# differential_evolution step 671: f(x)= 0.6876309516783682
# differential_evolution step 672: f(x)= 0.6876309516783682
# differential_evolution step 673: f(x)= 0.6876309516783682
# differential_evolution step 674: f(x)= 0.6168646726203704
# differential_evolution step 675: f(x)= 0.6168646726203704
# differential_evolution step 676: f(x)= 0.6168646726203704
# differential_evolution step 677: f(x)= 0.6168646726203704
# differential_evolution step 678: f(x)= 0.6085083213560802
# differential_evolution step 679: f(x)= 0.6085083213560802
# differential_evolution step 680: f(x)= 0.6085083213560802
# differential_evolution step 681: f(x)= 0.6085083213560802
# differential_evolution step 682: f(x)= 0.6085083213560802
# differential_evolution step 683: f(x)= 0.6085083213560802
# differential_evolution step 684: f(x)= 0.6085083213560802
# differential_evolution step 685: f(x)= 0.6085083213560802
# differential_evolution step 686: f(x)= 0.6085083213560802
# differential_evolution step 687: f(x)= 0.6085083213560802
# differential_evolution step 688: f(x)= 0.6085083213560802
# differential_evolution step 689: f(x)= 0.6085083213560802
# differential_evolution step 690: f(x)= 0.6085083213560802
# differential_evolution step 691: f(x)= 0.6085083213560802
# differential_evolution step 692: f(x)= 0.5468078921873102
# differential_evolution step 693: f(x)= 0.5468078921873102
# differential_evolution step 694: f(x)= 0.5468078921873102
# differential_evolution step 695: f(x)= 0.5468078921873102
# differential_evolution step 696: f(x)= 0.5468078921873102
# differential_evolution step 697: f(x)= 0.5468078921873102
# differential_evolution step 698: f(x)= 0.5468078921873102
# differential_evolution step 699: f(x)= 0.5468078921873102
# differential_evolution step 700: f(x)= 0.5468078921873102
# differential_evolution step 701: f(x)= 0.5468078921873102
# differential_evolution step 702: f(x)= 0.5468078921873102
# differential_evolution step 703: f(x)= 0.5468078921873102
# differential_evolution step 704: f(x)= 0.5468078921873102
# differential_evolution step 705: f(x)= 0.5468078921873102
# differential_evolution step 706: f(x)= 0.5468078921873102
# differential_evolution step 707: f(x)= 0.5468078921873102
# differential_evolution step 708: f(x)= 0.5468078921873102
# differential_evolution step 709: f(x)= 0.5468078921873102
# differential_evolution step 710: f(x)= 0.5468078921873102
# differential_evolution step 711: f(x)= 0.5468078921873102
# differential_evolution step 712: f(x)= 0.5468078921873102
# differential_evolution step 713: f(x)= 0.5468078921873102
# differential_evolution step 714: f(x)= 0.5468078921873102
# differential_evolution step 715: f(x)= 0.5468078921873102
# differential_evolution step 716: f(x)= 0.5468078921873102
# differential_evolution step 717: f(x)= 0.5468078921873102
# differential_evolution step 718: f(x)= 0.5410412822411246
# differential_evolution step 719: f(x)= 0.5410412822411246
# differential_evolution step 720: f(x)= 0.5410412822411246
# differential_evolution step 721: f(x)= 0.5410412822411246
# differential_evolution step 722: f(x)= 0.5410412822411246
# differential_evolution step 723: f(x)= 0.5410412822411246
# differential_evolution step 724: f(x)= 0.5410412822411246
# differential_evolution step 725: f(x)= 0.5410412822411246
# differential_evolution step 726: f(x)= 0.5410412822411246
# differential_evolution step 727: f(x)= 0.5410412822411246
# differential_evolution step 728: f(x)= 0.5410412822411246
# differential_evolution step 729: f(x)= 0.5410412822411246
# differential_evolution step 730: f(x)= 0.5410412822411246
# differential_evolution step 731: f(x)= 0.5410412822411246
# differential_evolution step 732: f(x)= 0.5410412822411246
# differential_evolution step 733: f(x)= 0.5410412822411246
# differential_evolution step 734: f(x)= 0.5410412822411246
# differential_evolution step 735: f(x)= 0.5410412822411246
# differential_evolution step 736: f(x)= 0.5410412822411246
# differential_evolution step 737: f(x)= 0.5410412822411246
# differential_evolution step 738: f(x)= 0.5410412822411246
# differential_evolution step 739: f(x)= 0.5410412822411246
# differential_evolution step 740: f(x)= 0.5410412822411246
# differential_evolution step 741: f(x)= 0.5398444667024194
# differential_evolution step 742: f(x)= 0.5398444667024194
# differential_evolution step 743: f(x)= 0.5398444667024194
# differential_evolution step 744: f(x)= 0.5398444667024194
# differential_evolution step 745: f(x)= 0.5398444667024194
# differential_evolution step 746: f(x)= 0.5398444667024194
# differential_evolution step 747: f(x)= 0.5398444667024194
# differential_evolution step 748: f(x)= 0.5398444667024194
# differential_evolution step 749: f(x)= 0.5398444667024194
# differential_evolution step 750: f(x)= 0.5398444667024194
# differential_evolution step 751: f(x)= 0.5398444667024194
# differential_evolution step 752: f(x)= 0.5398444667024194
# differential_evolution step 753: f(x)= 0.5398444667024194
# differential_evolution step 754: f(x)= 0.5398444667024194
# differential_evolution step 755: f(x)= 0.5398444667024194
# differential_evolution step 756: f(x)= 0.5398444667024194
# differential_evolution step 757: f(x)= 0.5398444667024194
# differential_evolution step 758: f(x)= 0.5398444667024194
# differential_evolution step 759: f(x)= 0.5398444667024194
# differential_evolution step 760: f(x)= 0.5398444667024194
# differential_evolution step 761: f(x)= 0.5398444667024194
# differential_evolution step 762: f(x)= 0.5398444667024194
# differential_evolution step 763: f(x)= 0.5398444667024194
# differential_evolution step 764: f(x)= 0.5398444667024194
# differential_evolution step 765: f(x)= 0.5398444667024194
# differential_evolution step 766: f(x)= 0.5398444667024194
# differential_evolution step 767: f(x)= 0.5398444667024194
# differential_evolution step 768: f(x)= 0.5398444667024194
# differential_evolution step 769: f(x)= 0.5398444667024194
# differential_evolution step 770: f(x)= 0.5325860293572996
# differential_evolution step 771: f(x)= 0.5325860293572996
# differential_evolution step 772: f(x)= 0.5325860293572996
# differential_evolution step 773: f(x)= 0.5325860293572996
# differential_evolution step 774: f(x)= 0.5325860293572996
# differential_evolution step 775: f(x)= 0.5325860293572996
# differential_evolution step 776: f(x)= 0.5325860293572996
# differential_evolution step 777: f(x)= 0.5325860293572996
# differential_evolution step 778: f(x)= 0.5325860293572996
# differential_evolution step 779: f(x)= 0.5325860293572996
# differential_evolution step 780: f(x)= 0.5325860293572996
# differential_evolution step 781: f(x)= 0.5325860293572996
# differential_evolution step 782: f(x)= 0.5325860293572996
# differential_evolution step 783: f(x)= 0.5325860293572996
# differential_evolution step 784: f(x)= 0.5325860293572996
# differential_evolution step 785: f(x)= 0.5325860293572996
# differential_evolution step 786: f(x)= 0.5325860293572996
# differential_evolution step 787: f(x)= 0.5325860293572996
# differential_evolution step 788: f(x)= 0.5325860293572996
# differential_evolution step 789: f(x)= 0.5325860293572996
# differential_evolution step 790: f(x)= 0.5325860293572996
# differential_evolution step 791: f(x)= 0.5325860293572996
# differential_evolution step 792: f(x)= 0.5325860293572996
# differential_evolution step 793: f(x)= 0.5325860293572996
# differential_evolution step 794: f(x)= 0.5325860293572996
# differential_evolution step 795: f(x)= 0.5325860293572996
# differential_evolution step 796: f(x)= 0.5325860293572996
# differential_evolution step 797: f(x)= 0.5325860293572996
# differential_evolution step 798: f(x)= 0.5325860293572996
# differential_evolution step 799: f(x)= 0.5325860293572996
# differential_evolution step 800: f(x)= 0.5325860293572996
# differential_evolution step 801: f(x)= 0.5325860293572996
# differential_evolution step 802: f(x)= 0.5325860293572996
# differential_evolution step 803: f(x)= 0.5325860293572996
# differential_evolution step 804: f(x)= 0.5325860293572996
# differential_evolution step 805: f(x)= 0.5325860293572996
# differential_evolution step 806: f(x)= 0.5325860293572996
# differential_evolution step 807: f(x)= 0.5325860293572996
# differential_evolution step 808: f(x)= 0.5325860293572996
# differential_evolution step 809: f(x)= 0.5325860293572996
# differential_evolution step 810: f(x)= 0.5325860293572996
# differential_evolution step 811: f(x)= 0.5325860293572996
# differential_evolution step 812: f(x)= 0.5325860293572996
# differential_evolution step 813: f(x)= 0.47703948309512617
# differential_evolution step 814: f(x)= 0.47703948309512617
# differential_evolution step 815: f(x)= 0.47703948309512617
# differential_evolution step 816: f(x)= 0.47703948309512617
# differential_evolution step 817: f(x)= 0.47703948309512617
# differential_evolution step 818: f(x)= 0.47703948309512617
# differential_evolution step 819: f(x)= 0.47703948309512617
# differential_evolution step 820: f(x)= 0.47703948309512617
# differential_evolution step 821: f(x)= 0.47703948309512617
# differential_evolution step 822: f(x)= 0.47703948309512617
# differential_evolution step 823: f(x)= 0.47703948309512617
# differential_evolution step 824: f(x)= 0.47703948309512617
# differential_evolution step 825: f(x)= 0.47703948309512617
# differential_evolution step 826: f(x)= 0.47703948309512617
# differential_evolution step 827: f(x)= 0.47703948309512617
# differential_evolution step 828: f(x)= 0.47703948309512617
# differential_evolution step 829: f(x)= 0.47703948309512617
# differential_evolution step 830: f(x)= 0.47703948309512617
# differential_evolution step 831: f(x)= 0.47703948309512617
# differential_evolution step 832: f(x)= 0.47703948309512617
# differential_evolution step 833: f(x)= 0.47703948309512617
# differential_evolution step 834: f(x)= 0.47703948309512617
# differential_evolution step 835: f(x)= 0.47703948309512617
# differential_evolution step 836: f(x)= 0.47703948309512617
# differential_evolution step 837: f(x)= 0.47703948309512617
# differential_evolution step 838: f(x)= 0.47703948309512617
# differential_evolution step 839: f(x)= 0.47703948309512617
# differential_evolution step 840: f(x)= 0.47703948309512617
# differential_evolution step 841: f(x)= 0.47703948309512617
# differential_evolution step 842: f(x)= 0.47703948309512617
# differential_evolution step 843: f(x)= 0.47703948309512617
# differential_evolution step 844: f(x)= 0.47703948309512617
# differential_evolution step 845: f(x)= 0.47703948309512617
# differential_evolution step 846: f(x)= 0.47703948309512617
# differential_evolution step 847: f(x)= 0.47703948309512617
# differential_evolution step 848: f(x)= 0.47703948309512617
# differential_evolution step 849: f(x)= 0.47703948309512617
# differential_evolution step 850: f(x)= 0.4434284037242393
# differential_evolution step 851: f(x)= 0.4434284037242393
# differential_evolution step 852: f(x)= 0.4434284037242393
# differential_evolution step 853: f(x)= 0.4434284037242393
# differential_evolution step 854: f(x)= 0.4434284037242393
# differential_evolution step 855: f(x)= 0.4434284037242393
# differential_evolution step 856: f(x)= 0.4434284037242393
# differential_evolution step 857: f(x)= 0.3960449687987125
# differential_evolution step 858: f(x)= 0.3960449687987125
# differential_evolution step 859: f(x)= 0.3960449687987125
# differential_evolution step 860: f(x)= 0.3960449687987125
# differential_evolution step 861: f(x)= 0.3960449687987125
# differential_evolution step 862: f(x)= 0.3960449687987125
# differential_evolution step 863: f(x)= 0.3960449687987125
# differential_evolution step 864: f(x)= 0.3960449687987125
# differential_evolution step 865: f(x)= 0.3960449687987125
# differential_evolution step 866: f(x)= 0.3960449687987125
# differential_evolution step 867: f(x)= 0.3960449687987125
# differential_evolution step 868: f(x)= 0.3960449687987125
# differential_evolution step 869: f(x)= 0.3960449687987125
# differential_evolution step 870: f(x)= 0.3960449687987125
# differential_evolution step 871: f(x)= 0.3960449687987125
# differential_evolution step 872: f(x)= 0.3960449687987125
# differential_evolution step 873: f(x)= 0.3960449687987125
# differential_evolution step 874: f(x)= 0.3960449687987125
# differential_evolution step 875: f(x)= 0.3960449687987125
# differential_evolution step 876: f(x)= 0.3960449687987125
# differential_evolution step 877: f(x)= 0.3684969403887314
# differential_evolution step 878: f(x)= 0.3684969403887314
# differential_evolution step 879: f(x)= 0.3684969403887314
# differential_evolution step 880: f(x)= 0.3684969403887314
# differential_evolution step 881: f(x)= 0.3684969403887314
# differential_evolution step 882: f(x)= 0.3684969403887314
# differential_evolution step 883: f(x)= 0.3684969403887314
# differential_evolution step 884: f(x)= 0.3684969403887314
# differential_evolution step 885: f(x)= 0.3684969403887314
# differential_evolution step 886: f(x)= 0.3684969403887314
# differential_evolution step 887: f(x)= 0.3684969403887314
# differential_evolution step 888: f(x)= 0.3684969403887314
# differential_evolution step 889: f(x)= 0.3684969403887314
# differential_evolution step 890: f(x)= 0.3516461618056559
# differential_evolution step 891: f(x)= 0.3516461618056559
# differential_evolution step 892: f(x)= 0.3516461618056559
# differential_evolution step 893: f(x)= 0.3516461618056559
# differential_evolution step 894: f(x)= 0.3516461618056559
# differential_evolution step 895: f(x)= 0.3516461618056559
# differential_evolution step 896: f(x)= 0.3516461618056559
# differential_evolution step 897: f(x)= 0.3516461618056559
# differential_evolution step 898: f(x)= 0.3516461618056559
# differential_evolution step 899: f(x)= 0.3516461618056559
# differential_evolution step 900: f(x)= 0.3516461618056559
# differential_evolution step 901: f(x)= 0.3516461618056559
# differential_evolution step 902: f(x)= 0.3516461618056559
# differential_evolution step 903: f(x)= 0.3516461618056559
# differential_evolution step 904: f(x)= 0.3516461618056559
# differential_evolution step 905: f(x)= 0.3516461618056559
# differential_evolution step 906: f(x)= 0.3516461618056559
# differential_evolution step 907: f(x)= 0.3516461618056559
# differential_evolution step 908: f(x)= 0.3516461618056559
# differential_evolution step 909: f(x)= 0.3516461618056559
# differential_evolution step 910: f(x)= 0.3516461618056559
# differential_evolution step 911: f(x)= 0.3516461618056559
# differential_evolution step 912: f(x)= 0.3516461618056559
# differential_evolution step 913: f(x)= 0.3516461618056559
# differential_evolution step 914: f(x)= 0.3516461618056559
# differential_evolution step 915: f(x)= 0.3516461618056559
# differential_evolution step 916: f(x)= 0.3516461618056559
# differential_evolution step 917: f(x)= 0.3516461618056559
# differential_evolution step 918: f(x)= 0.3516461618056559
# differential_evolution step 919: f(x)= 0.3516461618056559
# differential_evolution step 920: f(x)= 0.3516461618056559
# differential_evolution step 921: f(x)= 0.3516461618056559
# differential_evolution step 922: f(x)= 0.3516461618056559
# differential_evolution step 923: f(x)= 0.3516461618056559
# differential_evolution step 924: f(x)= 0.3516461618056559
# differential_evolution step 925: f(x)= 0.3516461618056559
# differential_evolution step 926: f(x)= 0.3516461618056559
# differential_evolution step 927: f(x)= 0.3516461618056559
# differential_evolution step 928: f(x)= 0.3516461618056559
# differential_evolution step 929: f(x)= 0.3516461618056559
# differential_evolution step 930: f(x)= 0.3516461618056559
# differential_evolution step 931: f(x)= 0.3516461618056559
# differential_evolution step 932: f(x)= 0.3516461618056559
# differential_evolution step 933: f(x)= 0.3516461618056559
# differential_evolution step 934: f(x)= 0.3516461618056559
# differential_evolution step 935: f(x)= 0.3516461618056559
# differential_evolution step 936: f(x)= 0.3516461618056559
# differential_evolution step 937: f(x)= 0.3516461618056559
# differential_evolution step 938: f(x)= 0.3516461618056559
# differential_evolution step 939: f(x)= 0.3516461618056559
# differential_evolution step 940: f(x)= 0.3516461618056559
# differential_evolution step 941: f(x)= 0.3516461618056559
# differential_evolution step 942: f(x)= 0.3516461618056559
# differential_evolution step 943: f(x)= 0.3516461618056559
# differential_evolution step 944: f(x)= 0.3516461618056559
# differential_evolution step 945: f(x)= 0.3516461618056559
# differential_evolution step 946: f(x)= 0.3516461618056559
# differential_evolution step 947: f(x)= 0.3516461618056559
# differential_evolution step 948: f(x)= 0.3254335584776645
# differential_evolution step 949: f(x)= 0.3254335584776645
# differential_evolution step 950: f(x)= 0.3254335584776645
# differential_evolution step 951: f(x)= 0.3254335584776645
# differential_evolution step 952: f(x)= 0.3254335584776645
# differential_evolution step 953: f(x)= 0.3254335584776645
# differential_evolution step 954: f(x)= 0.3254335584776645
# differential_evolution step 955: f(x)= 0.3254335584776645
# differential_evolution step 956: f(x)= 0.3254335584776645
# differential_evolution step 957: f(x)= 0.325106708119915
# differential_evolution step 958: f(x)= 0.325106708119915
# differential_evolution step 959: f(x)= 0.325106708119915
# differential_evolution step 960: f(x)= 0.325106708119915
# differential_evolution step 961: f(x)= 0.325106708119915
# differential_evolution step 962: f(x)= 0.325106708119915
# differential_evolution step 963: f(x)= 0.325106708119915
# differential_evolution step 964: f(x)= 0.325106708119915
# differential_evolution step 965: f(x)= 0.325106708119915
# differential_evolution step 966: f(x)= 0.325106708119915
# differential_evolution step 967: f(x)= 0.325106708119915
# differential_evolution step 968: f(x)= 0.325106708119915
# differential_evolution step 969: f(x)= 0.325106708119915
# differential_evolution step 970: f(x)= 0.325106708119915
# differential_evolution step 971: f(x)= 0.325106708119915
# differential_evolution step 972: f(x)= 0.325106708119915
# differential_evolution step 973: f(x)= 0.325106708119915
# differential_evolution step 974: f(x)= 0.325106708119915
# differential_evolution step 975: f(x)= 0.325106708119915
# differential_evolution step 976: f(x)= 0.325106708119915
# differential_evolution step 977: f(x)= 0.325106708119915
# differential_evolution step 978: f(x)= 0.325106708119915
# differential_evolution step 979: f(x)= 0.325106708119915
# differential_evolution step 980: f(x)= 0.325106708119915
# differential_evolution step 981: f(x)= 0.325106708119915
# differential_evolution step 982: f(x)= 0.325106708119915
# differential_evolution step 983: f(x)= 0.325106708119915
# differential_evolution step 984: f(x)= 0.325106708119915
# differential_evolution step 985: f(x)= 0.3176670749237716
# differential_evolution step 986: f(x)= 0.3176670749237716
# differential_evolution step 987: f(x)= 0.3176670749237716
# differential_evolution step 988: f(x)= 0.3176670749237716
# differential_evolution step 989: f(x)= 0.3143030327464051
# differential_evolution step 990: f(x)= 0.3143030327464051
# differential_evolution step 991: f(x)= 0.3143030327464051
# differential_evolution step 992: f(x)= 0.3143030327464051
# differential_evolution step 993: f(x)= 0.3143030327464051
# differential_evolution step 994: f(x)= 0.3143030327464051
# differential_evolution step 995: f(x)= 0.3143030327464051
# differential_evolution step 996: f(x)= 0.3143030327464051
# differential_evolution step 997: f(x)= 0.3143030327464051
# differential_evolution step 998: f(x)= 0.3143030327464051
# differential_evolution step 999: f(x)= 0.29322846067993436
# differential_evolution step 1000: f(x)= 0.29322846067993436
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [3.79264677e-01 3.39198260e+00 2.62230331e+00 2.88162040e+01
#  3.12847647e-01 3.16293565e+00 1.44014684e+00 5.70360329e+01
#  9.08637412e-02 1.35755165e+01 2.00117429e+00 7.73486859e+01
#  6.58390364e-01 1.59970942e+00 7.81839865e-01 8.30503753e+01
#  1.80896367e-01 4.39899214e+00 1.02429444e+00 1.42970555e+01
#  4.63278706e-02 2.27039319e+01 1.16577301e+00 6.95964034e+01
#  3.48460419e-02 8.57570449e+00 7.04906526e-01 5.08321767e+01
#  2.43364664e-02 1.94703947e+01 1.01371728e+00 1.83473458e+01]
# Chi quadro minimo: 0.2504626523384292

# %%
# Plots:
params_curve_8, covariance_8 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, 
                                         p0=best_params8, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[7], red_chi[7] = save_params(params_curve_8, covariance_8, radial_profile_HA, radial_profile_error_HA, x_axes, 8, 
                                       line_name="Eight", output_prefix="fit")

aic[7] = AIC(x_axes, radial_profile_HA, chi_quadr[7], params_curve_8)
bic[7] = BIC(x_axes, radial_profile_HA, chi_quadr[7], params_curve_8)
print(aic[7], chi_quadr[7], bic[7], len(best_params8))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_8)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[20:24]), linestyle='--', label='Sérsic 6')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[24:28]), linestyle='--', label='Sérsic 7')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params8[28:32]), linestyle='--', label='Sérsic 8')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)
plt.savefig('AIC_8', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\1396728411.py:14: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4673, r_e=2.9550, n=2.4318, x_0=28.8162
# Sérsic 2: I_e=0.2386, r_e=4.2322, n=1.5825, x_0=57.0748
# Sérsic 3: I_e=0.0695, r_e=8.0123, n=2.5367, x_0=77.3743
# Sérsic 4: I_e=0.9256, r_e=1.7194, n=0.4863, x_0=82.9394
# Sérsic 5: I_e=0.2507, r_e=2.7678, n=0.8109, x_0=14.1695
# Sérsic 6: I_e=0.0133, r_e=99.9954, n=2.2913, x_0=72.0653
# Sérsic 7: I_e=0.0553, r_e=1.4581, n=0.6342, x_0=49.8815
# Sérsic 8: I_e=0.0963, r_e=8.9946, n=0.3863, x_0=17.9352
# [7.60145686e-01 3.62786678e+00 2.10280611e+00 1.24982242e-02
#  2.05928636e-01 2.70193565e+00 6.56119343e-01 7.07918517e-02
#  2.56780437e-01 2.27019562e+01 2.85543815e+00 1.28027149e-01
#  3.40750982e-01 2.80560740e-01 3.14469454e-01 1.36403074e-01
#  1.68763056e-01 1.67151110e+00 5.42824573e-01 1.71041413e-01
#  4.82939580e-02 2.60952786e+02 2.58420069e+00 5.05902659e-01
#  3.06990346e-01 3.10732399e+00 4.79334194e+00 7.15410294e-01
#  4.02529253e-02 8.39404772e+00 3.48353074e-01 1.51174030e+01]
# 17.4354171854913
# 112.95780524519279 17.4354171854913 164.80086313711024 32
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6, 7, 8]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_5964\1271746709.py:25: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig3 = plt.figure(figsize=(8,6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
