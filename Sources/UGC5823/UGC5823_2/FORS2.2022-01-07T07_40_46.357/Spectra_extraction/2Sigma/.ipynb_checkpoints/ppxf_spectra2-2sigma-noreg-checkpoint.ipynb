# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_2/FORS2.2022-01-07T07_40_46.357/Spectra_extraction/redshift.txt")
z = red[1][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4370.75364254 4372.20673134 4373.65982013 ... 6964.51714252 6965.97023132
#  6967.42332011] [0.09277114 0.07691179 0.0886193  ... 0.06270323 0.06225437 0.06451373] [0.00712964 0.00712964 0.00712964 ... 0.00712964 0.00712964 0.00712964]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18537682 2.18610337 2.18682991 ... 3.48225857 3.48298512 3.48371166]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        28
# chi2/DOF: 0.008796; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
# chi2/DOF: 0.004662; DOF: 1901; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([4.00232605, 0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -143        54
#  comp.  1:         0        25
#  comp.  2:        -2        27
# chi2/DOF: 3.153; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.26      0.19       0    25
# Comp:  1                Halpha      232.7      0.19       0    25
# Comp:  2             [SII]6716      29.61      0.19      -2    27
# Comp:  2             [SII]6731      19.96      0.19      -2    27
# Comp:  2              HeII4687   0.007777      0.19      -2    27
# Comp:  2               HeI5876      8.009      0.19      -2    27
# Comp:  2          [OIII]5007_d      70.93      0.24      -2    27
# Comp:  2            [OI]6300_d      3.392      0.24      -2    27
# Comp:  2           [NII]6583_d      63.20      0.24      -2    27
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  256.5; gas flux:     59 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1056; gas flux:    319 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  133.9; gas flux:     41 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  87.41; gas flux:     28 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.03494; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  35.74; gas flux:     10 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:    232; gas flux:     74 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   10.9; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:    213; gas flux:     87 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:        -1        28
#  comp.  2:        -1        22
# chi2/DOF: 2.889; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.11      0.19      -1    28
# Comp:  1                Halpha      234.6      0.19      -1    28
# Comp:  2             [SII]6716      29.22      0.18      -1    22
# Comp:  2             [SII]6731      20.20      0.18      -1    22
# Comp:  2              HeII4687      0.000      0.18      -1    22
# Comp:  2               HeI5876      7.699      0.18      -1    22
# Comp:  2          [OIII]5007_d      70.35      0.23      -1    22
# Comp:  2            [OI]6300_d      2.988      0.23      -1    22
# Comp:  2           [NII]6583_d      62.16      0.23      -1    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:         2        27
#  comp.  2:        -2        26
# chi2/DOF: 2.754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.61      0.19       2    27
# Comp:  1                Halpha      232.6      0.19       2    27
# Comp:  2             [SII]6716      30.22      0.19      -2    26
# Comp:  2             [SII]6731      19.76      0.19      -2    26
# Comp:  2              HeII4687      0.000      0.19      -2    26
# Comp:  2               HeI5876      7.983      0.19      -2    26
# Comp:  2          [OIII]5007_d      72.37      0.24      -2    26
# Comp:  2            [OI]6300_d      3.545      0.24      -2    26
# Comp:  2           [NII]6583_d      61.80      0.24      -2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        25
#  comp.  1:        -0        23
#  comp.  2:        -2        25
# chi2/DOF: 2.998; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.23      0.19      -0    23
# Comp:  1                Halpha      232.2      0.19      -0    23
# Comp:  2             [SII]6716      28.52      0.19      -2    25
# Comp:  2             [SII]6731      20.49      0.19      -2    25
# Comp:  2              HeII4687    0.02739      0.19      -2    25
# Comp:  2               HeI5876      7.511      0.19      -2    25
# Comp:  2          [OIII]5007_d      68.51      0.24      -2    25
# Comp:  2            [OI]6300_d      3.307      0.24      -2    25
# Comp:  2           [NII]6583_d      61.78      0.24      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -195         1
#  comp.  1:         1        23
#  comp.  2:        -2        15
# chi2/DOF: 2.448; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      51.74      0.18       1    23
# Comp:  1                Halpha      229.4      0.18       1    23
# Comp:  2             [SII]6716      29.20      0.18      -2    15
# Comp:  2             [SII]6731      19.30      0.18      -2    15
# Comp:  2              HeII4687      0.000      0.18      -2    15
# Comp:  2               HeI5876      7.683      0.18      -2    15
# Comp:  2          [OIII]5007_d      68.38      0.23      -2    15
# Comp:  2            [OI]6300_d      3.022      0.23      -2    15
# Comp:  2           [NII]6583_d      60.84      0.23      -2    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       102         1
#  comp.  1:         1        25
#  comp.  2:        -2        25
# chi2/DOF: 2.869; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.81      0.19       1    25
# Comp:  1                Halpha      231.5      0.19       1    25
# Comp:  2             [SII]6716      29.90      0.19      -2    25
# Comp:  2             [SII]6731      19.23      0.19      -2    25
# Comp:  2              HeII4687   0.003836      0.19      -2    25
# Comp:  2               HeI5876      7.597      0.19      -2    25
# Comp:  2          [OIII]5007_d      72.27      0.23      -2    25
# Comp:  2            [OI]6300_d      3.381      0.23      -2    25
# Comp:  2           [NII]6583_d      62.78      0.23      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10       104
#  comp.  1:         1        19
#  comp.  2:        -1        28
# chi2/DOF: 2.730; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.25      0.18       1    19
# Comp:  1                Halpha      230.5      0.18       1    19
# Comp:  2             [SII]6716      28.91      0.19      -1    28
# Comp:  2             [SII]6731      20.38      0.19      -1    28
# Comp:  2              HeII4687      0.000      0.19      -1    28
# Comp:  2               HeI5876      8.171      0.19      -1    28
# Comp:  2          [OIII]5007_d      69.66      0.24      -1    28
# Comp:  2            [OI]6300_d      3.326      0.24      -1    28
# Comp:  2           [NII]6583_d      64.88      0.24      -1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -182        17
#  comp.  1:         1        22
#  comp.  2:        -6        30
# chi2/DOF: 2.856; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.81      0.18       1    22
# Comp:  1                Halpha      229.4      0.18       1    22
# Comp:  2             [SII]6716      29.94      0.19      -6    30
# Comp:  2             [SII]6731      20.36      0.19      -6    30
# Comp:  2              HeII4687  0.0001300      0.19      -6    30
# Comp:  2               HeI5876      8.234      0.19      -6    30
# Comp:  2          [OIII]5007_d      71.79      0.24      -6    30
# Comp:  2            [OI]6300_d      3.461      0.24      -6    30
# Comp:  2           [NII]6583_d      62.33      0.24      -6    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       145         1
#  comp.  1:         1        26
#  comp.  2:        -2        31
# chi2/DOF: 2.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.87      0.19       1    26
# Comp:  1                Halpha      231.6      0.19       1    26
# Comp:  2             [SII]6716      29.71      0.19      -2    31
# Comp:  2             [SII]6731      19.96      0.19      -2    31
# Comp:  2              HeII4687    0.01443      0.19      -2    31
# Comp:  2               HeI5876      7.600      0.19      -2    31
# Comp:  2          [OIII]5007_d      71.29      0.24      -2    31
# Comp:  2            [OI]6300_d      3.782      0.24      -2    31
# Comp:  2           [NII]6583_d      62.91      0.24      -2    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -184         1
#  comp.  1:         1        22
#  comp.  2:        -1        27
# chi2/DOF: 2.495; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      51.68      0.18       1    22
# Comp:  1                Halpha      229.1      0.18       1    22
# Comp:  2             [SII]6716      29.98      0.19      -1    27
# Comp:  2             [SII]6731      19.93      0.19      -1    27
# Comp:  2              HeII4687    0.05214      0.19      -1    27
# Comp:  2               HeI5876      7.695      0.19      -1    27
# Comp:  2          [OIII]5007_d      69.82      0.24      -1    27
# Comp:  2            [OI]6300_d      3.451      0.24      -1    27
# Comp:  2           [NII]6583_d      62.52      0.24      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -161        68
#  comp.  1:         1        26
#  comp.  2:        -3        26
# chi2/DOF: 3.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.84      0.19       1    26
# Comp:  1                Halpha      232.6      0.19       1    26
# Comp:  2             [SII]6716      29.73      0.19      -3    26
# Comp:  2             [SII]6731      19.59      0.19      -3    26
# Comp:  2              HeII4687      0.000      0.19      -3    26
# Comp:  2               HeI5876      8.112      0.19      -3    26
# Comp:  2          [OIII]5007_d      72.10      0.24      -3    26
# Comp:  2            [OI]6300_d      3.467      0.24      -3    26
# Comp:  2           [NII]6583_d      61.85      0.24      -3    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:         0        23
#  comp.  2:        -1        17
# chi2/DOF: 2.412; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.14      0.19       0    23
# Comp:  1                Halpha      233.8      0.19       0    23
# Comp:  2             [SII]6716      29.17      0.18      -1    17
# Comp:  2             [SII]6731      19.18      0.18      -1    17
# Comp:  2              HeII4687   0.007666      0.18      -1    17
# Comp:  2               HeI5876      8.614      0.18      -1    17
# Comp:  2          [OIII]5007_d      66.76      0.23      -1    17
# Comp:  2            [OI]6300_d      3.381      0.23      -1    17
# Comp:  2           [NII]6583_d      63.24      0.23      -1    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -220         1
#  comp.  1:        -1        27
#  comp.  2:        -5        27
# chi2/DOF: 2.364; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.23      0.19      -1    27
# Comp:  1                Halpha      235.3      0.19      -1    27
# Comp:  2             [SII]6716      29.03      0.19      -5    27
# Comp:  2             [SII]6731      20.25      0.19      -5    27
# Comp:  2              HeII4687   0.009663      0.19      -5    27
# Comp:  2               HeI5876      8.594      0.19      -5    27
# Comp:  2          [OIII]5007_d      70.16      0.24      -5    27
# Comp:  2            [OI]6300_d      3.380      0.24      -5    27
# Comp:  2           [NII]6583_d      62.66      0.24      -5    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136        41
#  comp.  1:        -1        25
#  comp.  2:        -5        27
# chi2/DOF: 2.541; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.61      0.19      -1    25
# Comp:  1                Halpha      232.7      0.19      -1    25
# Comp:  2             [SII]6716      30.43      0.19      -5    27
# Comp:  2             [SII]6731      20.49      0.19      -5    27
# Comp:  2              HeII4687      0.000      0.19      -5    27
# Comp:  2               HeI5876      7.685      0.19      -5    27
# Comp:  2          [OIII]5007_d      71.38      0.24      -5    27
# Comp:  2            [OI]6300_d      3.268      0.24      -5    27
# Comp:  2           [NII]6583_d      62.40      0.24      -5    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158         1
#  comp.  1:         0        26
#  comp.  2:        -3        27
# chi2/DOF: 2.549; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.35      0.19       0    26
# Comp:  1                Halpha      230.9      0.19       0    26
# Comp:  2             [SII]6716      30.35      0.19      -3    27
# Comp:  2             [SII]6731      20.33      0.19      -3    27
# Comp:  2              HeII4687   0.006055      0.19      -3    27
# Comp:  2               HeI5876      8.472      0.19      -3    27
# Comp:  2          [OIII]5007_d      69.79      0.24      -3    27
# Comp:  2            [OI]6300_d      3.334      0.24      -3    27
# Comp:  2           [NII]6583_d      62.88      0.24      -3    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160         1
#  comp.  1:         2        22
#  comp.  2:        -4        29
# chi2/DOF: 1.899; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.69      0.18       2    22
# Comp:  1                Halpha      231.6      0.18       2    22
# Comp:  2             [SII]6716      30.63      0.19      -4    29
# Comp:  2             [SII]6731      19.50      0.19      -4    29
# Comp:  2              HeII4687      0.000      0.19      -4    29
# Comp:  2               HeI5876      8.652      0.19      -4    29
# Comp:  2          [OIII]5007_d      72.11      0.24      -4    29
# Comp:  2            [OI]6300_d      3.454      0.24      -4    29
# Comp:  2           [NII]6583_d      63.77      0.24      -4    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -186        67
#  comp.  1:         1        23
#  comp.  2:        -3        37
# chi2/DOF: 2.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.71      0.19       1    23
# Comp:  1                Halpha      230.8      0.19       1    23
# Comp:  2             [SII]6716      30.14      0.19      -3    37
# Comp:  2             [SII]6731      20.68      0.19      -3    37
# Comp:  2              HeII4687   0.001212      0.19      -3    37
# Comp:  2               HeI5876      7.717      0.19      -3    37
# Comp:  2          [OIII]5007_d      75.50      0.24      -3    37
# Comp:  2            [OI]6300_d      3.368      0.24      -3    37
# Comp:  2           [NII]6583_d      65.10      0.24      -3    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122         6
#  comp.  1:         1        24
#  comp.  2:        -1        14
# chi2/DOF: 2.057; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.22      0.19       1    24
# Comp:  1                Halpha      232.9      0.19       1    24
# Comp:  2             [SII]6716      29.29      0.18      -1    14
# Comp:  2             [SII]6731      19.09      0.18      -1    14
# Comp:  2              HeII4687    0.01348      0.18      -1    14
# Comp:  2               HeI5876      7.379      0.18      -1    14
# Comp:  2          [OIII]5007_d      66.30      0.23      -1    14
# Comp:  2            [OI]6300_d      3.156      0.23      -1    14
# Comp:  2           [NII]6583_d      62.57      0.23      -1    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -184        74
#  comp.  1:         1        27
#  comp.  2:        -1        33
# chi2/DOF: 2.087; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.96      0.19       1    27
# Comp:  1                Halpha      234.7      0.19       1    27
# Comp:  2             [SII]6716      30.41      0.19      -1    33
# Comp:  2             [SII]6731      19.57      0.19      -1    33
# Comp:  2              HeII4687      0.000      0.19      -1    33
# Comp:  2               HeI5876      8.279      0.19      -1    33
# Comp:  2          [OIII]5007_d      73.88      0.24      -1    33
# Comp:  2            [OI]6300_d      3.144      0.24      -1    33
# Comp:  2           [NII]6583_d      64.29      0.24      -1    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105         1
#  comp.  1:         0        26
#  comp.  2:         1        19
# chi2/DOF: 2.004; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.41      0.19       0    26
# Comp:  1                Halpha      233.3      0.19       0    26
# Comp:  2             [SII]6716      30.02      0.18       1    19
# Comp:  2             [SII]6731      19.44      0.18       1    19
# Comp:  2              HeII4687      0.000      0.18       1    19
# Comp:  2               HeI5876      7.496      0.18       1    19
# Comp:  2          [OIII]5007_d      68.51      0.23       1    19
# Comp:  2            [OI]6300_d      3.738      0.23       1    19
# Comp:  2           [NII]6583_d      61.30      0.23       1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115         1
#  comp.  1:        -0        28
#  comp.  2:        -5        34
# chi2/DOF: 1.957; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.53      0.19      -0    28
# Comp:  1                Halpha      234.7      0.19      -0    28
# Comp:  2             [SII]6716      29.25      0.19      -5    34
# Comp:  2             [SII]6731      20.95      0.19      -5    34
# Comp:  2              HeII4687      0.000      0.19      -5    34
# Comp:  2               HeI5876      7.219      0.19      -5    34
# Comp:  2          [OIII]5007_d      73.35      0.24      -5    34
# Comp:  2            [OI]6300_d      3.550      0.24      -5    34
# Comp:  2           [NII]6583_d      64.12      0.24      -5    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16       145
#  comp.  1:         0        23
#  comp.  2:        -4        36
# chi2/DOF: 1.986; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.02      0.19       0    23
# Comp:  1                Halpha      230.2      0.19       0    23
# Comp:  2             [SII]6716      30.21      0.19      -4    36
# Comp:  2             [SII]6731      21.20      0.19      -4    36
# Comp:  2              HeII4687    0.02147      0.19      -4    36
# Comp:  2               HeI5876      8.802      0.19      -4    36
# Comp:  2          [OIII]5007_d      74.88      0.24      -4    36
# Comp:  2            [OI]6300_d      3.833      0.24      -4    36
# Comp:  2           [NII]6583_d      64.78      0.24      -4    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -176        39
#  comp.  1:         1        25
#  comp.  2:        -3        27
# chi2/DOF: 2.960; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.56      0.19       1    25
# Comp:  1                Halpha      231.7      0.19       1    25
# Comp:  2             [SII]6716      30.26      0.19      -3    27
# Comp:  2             [SII]6731      19.61      0.19      -3    27
# Comp:  2              HeII4687    0.05885      0.19      -3    27
# Comp:  2               HeI5876      8.517      0.19      -3    27
# Comp:  2          [OIII]5007_d      73.32      0.24      -3    27
# Comp:  2            [OI]6300_d      3.534      0.24      -3    27
# Comp:  2           [NII]6583_d      62.64      0.24      -3    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135         1
#  comp.  1:        -0        23
#  comp.  2:        -3        34
# chi2/DOF: 2.925; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.88      0.19      -0    23
# Comp:  1                Halpha      233.3      0.19      -0    23
# Comp:  2             [SII]6716      30.75      0.19      -3    34
# Comp:  2             [SII]6731      20.62      0.19      -3    34
# Comp:  2              HeII4687      0.000      0.19      -3    34
# Comp:  2               HeI5876      7.641      0.19      -3    34
# Comp:  2          [OIII]5007_d      74.44      0.24      -3    34
# Comp:  2            [OI]6300_d      3.525      0.24      -3    34
# Comp:  2           [NII]6583_d      64.67      0.24      -3    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116         1
#  comp.  1:        -1        24
#  comp.  2:        -5        33
# chi2/DOF: 2.808; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.78      0.19      -1    24
# Comp:  1                Halpha      235.0      0.19      -1    24
# Comp:  2             [SII]6716      30.49      0.19      -5    33
# Comp:  2             [SII]6731      20.71      0.19      -5    33
# Comp:  2              HeII4687      0.000      0.19      -5    33
# Comp:  2               HeI5876      8.668      0.19      -5    33
# Comp:  2          [OIII]5007_d      74.11      0.24      -5    33
# Comp:  2            [OI]6300_d      3.505      0.24      -5    33
# Comp:  2           [NII]6583_d      63.60      0.24      -5    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -162        79
#  comp.  1:         1        25
#  comp.  2:        -4        37
# chi2/DOF: 2.768; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.36      0.19       1    25
# Comp:  1                Halpha      231.3      0.19       1    25
# Comp:  2             [SII]6716      31.77      0.19      -4    37
# Comp:  2             [SII]6731      20.53      0.19      -4    37
# Comp:  2              HeII4687    0.08349      0.19      -4    37
# Comp:  2               HeI5876      8.103      0.19      -4    37
# Comp:  2          [OIII]5007_d      76.39      0.24      -4    37
# Comp:  2            [OI]6300_d      3.262      0.24      -4    37
# Comp:  2           [NII]6583_d      65.97      0.24      -4    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        71        44
#  comp.  1:         1        21
#  comp.  2:        -3        33
# chi2/DOF: 2.808; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.78      0.18       1    21
# Comp:  1                Halpha      230.6      0.18       1    21
# Comp:  2             [SII]6716      29.19      0.19      -3    33
# Comp:  2             [SII]6731      20.49      0.19      -3    33
# Comp:  2              HeII4687      0.000      0.19      -3    33
# Comp:  2               HeI5876      9.046      0.19      -3    33
# Comp:  2          [OIII]5007_d      74.58      0.24      -3    33
# Comp:  2            [OI]6300_d      3.401      0.24      -3    33
# Comp:  2           [NII]6583_d      63.19      0.24      -3    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       107         1
#  comp.  1:        -1        26
#  comp.  2:        -4        28
# chi2/DOF: 2.655; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.85      0.19      -1    26
# Comp:  1                Halpha      235.9      0.19      -1    26
# Comp:  2             [SII]6716      29.81      0.19      -4    28
# Comp:  2             [SII]6731      19.42      0.19      -4    28
# Comp:  2              HeII4687      0.000      0.19      -4    28
# Comp:  2               HeI5876      7.796      0.19      -4    28
# Comp:  2          [OIII]5007_d      72.72      0.24      -4    28
# Comp:  2            [OI]6300_d      3.393      0.24      -4    28
# Comp:  2           [NII]6583_d      63.29      0.24      -4    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        52
#  comp.  1:         0        22
#  comp.  2:        -5        31
# chi2/DOF: 2.504; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.37      0.18       0    22
# Comp:  1                Halpha      232.9      0.18       0    22
# Comp:  2             [SII]6716      29.63      0.19      -5    31
# Comp:  2             [SII]6731      20.63      0.19      -5    31
# Comp:  2              HeII4687      0.000      0.19      -5    31
# Comp:  2               HeI5876      8.257      0.19      -5    31
# Comp:  2          [OIII]5007_d      70.79      0.24      -5    31
# Comp:  2            [OI]6300_d      3.641      0.24      -5    31
# Comp:  2           [NII]6583_d      64.74      0.24      -5    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -203         1
#  comp.  1:        -1        24
#  comp.  2:        -1        21
# chi2/DOF: 2.058; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.65      0.19      -1    24
# Comp:  1                Halpha      233.7      0.19      -1    24
# Comp:  2             [SII]6716      28.53      0.18      -1    21
# Comp:  2             [SII]6731      20.15      0.18      -1    21
# Comp:  2              HeII4687    0.04252      0.18      -1    21
# Comp:  2               HeI5876      7.585      0.18      -1    21
# Comp:  2          [OIII]5007_d      68.65      0.23      -1    21
# Comp:  2            [OI]6300_d      3.477      0.23      -1    21
# Comp:  2           [NII]6583_d      63.87      0.23      -1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:         2        22
#  comp.  2:        -2        22
# chi2/DOF: 2.309; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.59      0.18       2    22
# Comp:  1                Halpha      230.4      0.18       2    22
# Comp:  2             [SII]6716      29.58      0.18      -2    22
# Comp:  2             [SII]6731      19.94      0.18      -2    22
# Comp:  2              HeII4687      0.000      0.18      -2    22
# Comp:  2               HeI5876      7.553      0.18      -2    22
# Comp:  2          [OIII]5007_d      69.69      0.23      -2    22
# Comp:  2            [OI]6300_d      3.382      0.23      -2    22
# Comp:  2           [NII]6583_d      64.14      0.23      -2    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -197        98
#  comp.  1:         1        26
#  comp.  2:        -4        33
# chi2/DOF: 2.956; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.13      0.19       1    26
# Comp:  1                Halpha      231.7      0.19       1    26
# Comp:  2             [SII]6716      30.45      0.19      -4    33
# Comp:  2             [SII]6731      20.78      0.19      -4    33
# Comp:  2              HeII4687   0.002119      0.19      -4    33
# Comp:  2               HeI5876      7.812      0.19      -4    33
# Comp:  2          [OIII]5007_d      71.90      0.24      -4    33
# Comp:  2            [OI]6300_d      3.211      0.24      -4    33
# Comp:  2           [NII]6583_d      64.37      0.24      -4    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23       215
#  comp.  1:         1        24
#  comp.  2:         2        25
# chi2/DOF: 2.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.70      0.19       1    24
# Comp:  1                Halpha      231.1      0.19       1    24
# Comp:  2             [SII]6716      29.35      0.19       2    25
# Comp:  2             [SII]6731      20.05      0.19       2    25
# Comp:  2              HeII4687    0.04040      0.19       2    25
# Comp:  2               HeI5876      7.575      0.19       2    25
# Comp:  2          [OIII]5007_d      70.82      0.23       2    25
# Comp:  2            [OI]6300_d      3.365      0.23       2    25
# Comp:  2           [NII]6583_d      62.19      0.23       2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:         1        20
#  comp.  2:         0        24
# chi2/DOF: 2.307; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.94      0.18       1    20
# Comp:  1                Halpha      227.9      0.18       1    20
# Comp:  2             [SII]6716      29.55      0.19       0    24
# Comp:  2             [SII]6731      19.19      0.19       0    24
# Comp:  2              HeII4687      0.000      0.19       0    24
# Comp:  2               HeI5876      8.434      0.19       0    24
# Comp:  2          [OIII]5007_d      71.18      0.23       0    24
# Comp:  2            [OI]6300_d      3.276      0.23       0    24
# Comp:  2           [NII]6583_d      62.71      0.23       0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        52
#  comp.  1:         2        22
#  comp.  2:         1        23
# chi2/DOF: 2.691; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.15      0.18       2    22
# Comp:  1                Halpha      231.6      0.18       2    22
# Comp:  2             [SII]6716      30.48      0.19       1    23
# Comp:  2             [SII]6731      19.80      0.19       1    23
# Comp:  2              HeII4687    0.02862      0.19       1    23
# Comp:  2               HeI5876      7.450      0.19       1    23
# Comp:  2          [OIII]5007_d      70.36      0.23       1    23
# Comp:  2            [OI]6300_d      3.201      0.23       1    23
# Comp:  2           [NII]6583_d      60.65      0.23       1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145         1
#  comp.  1:         0        24
#  comp.  2:        -4        27
# chi2/DOF: 3.065; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.89      0.19       0    24
# Comp:  1                Halpha      233.3      0.19       0    24
# Comp:  2             [SII]6716      29.93      0.19      -4    27
# Comp:  2             [SII]6731      19.51      0.19      -4    27
# Comp:  2              HeII4687   0.008398      0.19      -4    27
# Comp:  2               HeI5876      8.454      0.19      -4    27
# Comp:  2          [OIII]5007_d      71.45      0.24      -4    27
# Comp:  2            [OI]6300_d      3.464      0.24      -4    27
# Comp:  2           [NII]6583_d      62.60      0.24      -4    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -177        73
#  comp.  1:         1        27
#  comp.  2:        -2        27
# chi2/DOF: 2.907; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.84      0.19       1    27
# Comp:  1                Halpha      234.4      0.19       1    27
# Comp:  2             [SII]6716      30.74      0.19      -2    27
# Comp:  2             [SII]6731      20.59      0.19      -2    27
# Comp:  2              HeII4687    0.03900      0.19      -2    27
# Comp:  2               HeI5876      8.338      0.19      -2    27
# Comp:  2          [OIII]5007_d      70.95      0.24      -2    27
# Comp:  2            [OI]6300_d      3.716      0.24      -2    27
# Comp:  2           [NII]6583_d      64.11      0.24      -2    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:        -0        25
#  comp.  2:         1        23
# chi2/DOF: 2.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.89      0.19      -0    25
# Comp:  1                Halpha      235.0      0.19      -0    25
# Comp:  2             [SII]6716      28.76      0.19       1    23
# Comp:  2             [SII]6731      19.65      0.19       1    23
# Comp:  2              HeII4687      0.000      0.19       1    23
# Comp:  2               HeI5876      7.934      0.19       1    23
# Comp:  2          [OIII]5007_d      69.58      0.23       1    23
# Comp:  2            [OI]6300_d      3.345      0.23       1    23
# Comp:  2           [NII]6583_d      63.50      0.23       1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       175
#  comp.  1:         1        26
#  comp.  2:        -3        33
# chi2/DOF: 2.087; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.73      0.19       1    26
# Comp:  1                Halpha      231.4      0.19       1    26
# Comp:  2             [SII]6716      30.25      0.19      -3    33
# Comp:  2             [SII]6731      20.57      0.19      -3    33
# Comp:  2              HeII4687    0.03320      0.19      -3    33
# Comp:  2               HeI5876      7.993      0.19      -3    33
# Comp:  2          [OIII]5007_d      75.94      0.24      -3    33
# Comp:  2            [OI]6300_d      3.540      0.24      -3    33
# Comp:  2           [NII]6583_d      64.66      0.24      -3    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:         2        22
#  comp.  2:         0        24
# chi2/DOF: 2.821; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 75; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.16      0.18       2    22
# Comp:  1                Halpha      230.8      0.18       2    22
# Comp:  2             [SII]6716      29.99      0.19       0    24
# Comp:  2             [SII]6731      19.64      0.19       0    24
# Comp:  2              HeII4687    0.01882      0.19       0    24
# Comp:  2               HeI5876      8.533      0.19       0    24
# Comp:  2          [OIII]5007_d      70.11      0.23       0    24
# Comp:  2            [OI]6300_d      3.069      0.23       0    24
# Comp:  2           [NII]6583_d      62.06      0.23       0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180         1
#  comp.  1:         1        25
#  comp.  2:        -3        33
# chi2/DOF: 2.779; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.91      0.19       1    25
# Comp:  1                Halpha      230.1      0.19       1    25
# Comp:  2             [SII]6716      30.30      0.19      -3    33
# Comp:  2             [SII]6731      19.91      0.19      -3    33
# Comp:  2              HeII4687      0.000      0.19      -3    33
# Comp:  2               HeI5876      8.314      0.19      -3    33
# Comp:  2          [OIII]5007_d      74.66      0.24      -3    33
# Comp:  2            [OI]6300_d      3.161      0.24      -3    33
# Comp:  2           [NII]6583_d      63.37      0.24      -3    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102         1
#  comp.  1:        -0        26
#  comp.  2:        -1        26
# chi2/DOF: 2.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.74      0.19      -0    26
# Comp:  1                Halpha      235.8      0.19      -0    26
# Comp:  2             [SII]6716      29.35      0.19      -1    26
# Comp:  2             [SII]6731      20.21      0.19      -1    26
# Comp:  2              HeII4687    0.01585      0.19      -1    26
# Comp:  2               HeI5876      7.855      0.19      -1    26
# Comp:  2          [OIII]5007_d      68.75      0.24      -1    26
# Comp:  2            [OI]6300_d      3.266      0.24      -1    26
# Comp:  2           [NII]6583_d      62.24      0.24      -1    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       148         1
#  comp.  1:        -1        25
#  comp.  2:        -2        33
# chi2/DOF: 1.863; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.71      0.19      -1    25
# Comp:  1                Halpha      235.6      0.19      -1    25
# Comp:  2             [SII]6716      28.97      0.19      -2    33
# Comp:  2             [SII]6731      20.38      0.19      -2    33
# Comp:  2              HeII4687      0.000      0.19      -2    33
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.16      0.19       2    25
# Comp:  1                Halpha      230.2      0.19       2    25
# Comp:  2             [SII]6716      28.87      0.18       0    19
# Comp:  2             [SII]6731      19.86      0.18       0    19
# Comp:  2              HeII4687    0.02786      0.18       0    19
# Comp:  2               HeI5876      7.615      0.18       0    19
# Comp:  2          [OIII]5007_d      69.37      0.23       0    19
# Comp:  2            [OI]6300_d      3.439      0.23       0    19
# Comp:  2           [NII]6583_d      61.51      0.23       0    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146        80
#  comp.  1:         0        28
#  comp.  2:         2        27
# chi2/DOF: 2.859; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.71      0.19       0    28
# Comp:  1                Halpha      235.1      0.19       0    28
# Comp:  2             [SII]6716      29.56      0.19       2    27
# Comp:  2             [SII]6731      19.96      0.19       2    27
# Comp:  2              HeII4687    0.05771      0.19       2    27
# Comp:  2               HeI5876      7.617      0.19       2    27
# Comp:  2          [OIII]5007_d      70.65      0.24       2    27
# Comp:  2            [OI]6300_d      3.577      0.24       2    27
# Comp:  2           [NII]6583_d      62.07      0.24       2    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:         0        28
#  comp.  2:        -3        31
# chi2/DOF: 2.871; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.33      0.19       0    28
# Comp:  1                Halpha      236.1      0.19       0    28
# Comp:  2             [SII]6716      29.34      0.19      -3    31
# Comp:  2             [SII]6731      20.53      0.19      -3    31
# Comp:  2              HeII4687      0.000      0.19      -3    31
# Comp:  2               HeI5876      9.136      0.19      -3    31
# Comp:  2          [OIII]5007_d      72.13      0.24      -3    31
# Comp:  2            [OI]6300_d      3.573      0.24      -3    31
# Comp:  2           [NII]6583_d      65.10      0.24      -3    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147         1
#  comp.  1:         0        26
#  comp.  2:        -2        13
# chi2/DOF: 2.933; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.69      0.19       0    26
# Comp:  1                Halpha      233.1      0.19       0    26
# Comp:  2             [SII]6716      28.95      0.18      -2    13
# Comp:  2             [SII]6731      19.43      0.18      -2    13
# Comp:  2              HeII4687      0.000      0.18      -2    13
# Comp:  2               HeI5876      7.756      0.18      -2    13
# Comp:  2          [OIII]5007_d      67.22      0.23      -2    13
# Comp:  2            [OI]6300_d      3.342      0.23      -2    13
# Comp:  2           [NII]6583_d      61.07      0.23      -2    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:        -0        21
#  comp.  2:        -4        25
# chi2/DOF: 2.489; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.36      0.18      -0    21
# Comp:  1                Halpha      232.1      0.18      -0    21
# Comp:  2             [SII]6716      29.74      0.19      -4    25
# Comp:  2             [SII]6731      20.50      0.19      -4    25
# Comp:  2              HeII4687      0.000      0.19      -4    25
# Comp:  2               HeI5876      7.522      0.19      -4    25
# Comp:  2          [OIII]5007_d      69.39      0.24      -4    25
# Comp:  2            [OI]6300_d      3.286      0.24      -4    25
# Comp:  2           [NII]6583_d      63.94      0.24      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       144         1
#  comp.  1:         1        23
#  comp.  2:        -2        13
# chi2/DOF: 1.933; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.21      0.19       1    23
# Comp:  1                Halpha      232.3      0.19       1    23
# Comp:  2             [SII]6716      28.51      0.18      -2    13
# Comp:  2             [SII]6731      19.69      0.18      -2    13
# Comp:  2              HeII4687      0.000      0.18      -2    13
# Comp:  2               HeI5876      7.787      0.18      -2    13
# Comp:  2          [OIII]5007_d      66.96      0.23      -2    13
# Comp:  2            [OI]6300_d      2.934      0.23      -2    13
# Comp:  2           [NII]6583_d      61.25      0.23      -2    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -182        30
#  comp.  1:         1        25
#  comp.  2:         0        26
# chi2/DOF: 3.006; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.15      0.19       1    25
# Comp:  1                Halpha      231.3      0.19       1    25
# Comp:  2             [SII]6716      28.63      0.19       0    26
# Comp:  2             [SII]6731      19.63      0.19       0    26
# Comp:  2              HeII4687    0.03949      0.19       0    26
# Comp:  2               HeI5876      8.447      0.19       0    26
# Comp:  2          [OIII]5007_d      70.24      0.24       0    26
# Comp:  2            [OI]6300_d      3.307      0.24       0    26
# Comp:  2           [NII]6583_d      63.65      0.24       0    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137        47
#  comp.  1:        -1        24
#  comp.  2:        -4        23
# chi2/DOF: 2.909; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.75      0.19      -1    24
# Comp:  1                Halpha      235.1      0.19      -1    24
# Comp:  2             [SII]6716      30.06      0.19      -4    23
# Comp:  2             [SII]6731      19.68      0.19      -4    23
# Comp:  2              HeII4687      0.000      0.19      -4    23
# Comp:  2               HeI5876      7.919      0.19      -4    23
# Comp:  2          [OIII]5007_d      71.20      0.23      -4    23
# Comp:  2            [OI]6300_d      3.248      0.23      -4    23
# Comp:  2           [NII]6583_d      63.21      0.23      -4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141         1
#  comp.  1:        -1        26
#  comp.  2:        -4        35
# chi2/DOF: 1.988; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.42      0.19      -1    26
# Comp:  1                Halpha      233.7      0.19      -1    26
# Comp:  2             [SII]6716      30.12      0.19      -4    35
# Comp:  2             [SII]6731      21.09      0.19      -4    35
# Comp:  2              HeII4687    0.01514      0.19      -4    35
# Comp:  2               HeI5876      8.406      0.19      -4    35
# Comp:  2          [OIII]5007_d      72.52      0.24      -4    35
# Comp:  2            [OI]6300_d      3.282      0.24      -4    35
# Comp:  2           [NII]6583_d      63.98      0.24      -4    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -206        39
#  comp.  1:         0        29
#  comp.  2:        -0        20
# chi2/DOF: 2.832; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.57      0.19       0    29
# Comp:  1                Halpha      236.1      0.19       0    29
# Comp:  2             [SII]6716      29.62      0.18      -0    20
# Comp:  2             [SII]6731      19.48      0.18      -0    20
# Comp:  2              HeII4687    0.03379      0.18      -0    20
# Comp:  2               HeI5876      7.848      0.18      -0    20
# Comp:  2          [OIII]5007_d      69.48      0.23      -0    20
# Comp:  2            [OI]6300_d      3.423      0.23      -0    20
# Comp:  2           [NII]6583_d      61.65      0.23      -0    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -162        71
#  comp.  1:         1        27
#  comp.  2:        -2        19
# chi2/DOF: 2.850; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.31      0.19       1    27
# Comp:  1                Halpha      231.6      0.19       1    27
# Comp:  2             [SII]6716      29.22      0.18      -2    19
# Comp:  2             [SII]6731      19.52      0.18      -2    19
# Comp:  2              HeII4687    0.05610      0.18      -2    19
# Comp:  2               HeI5876      7.498      0.18      -2    19
# Comp:  2          [OIII]5007_d      68.31      0.23      -2    19
# Comp:  2            [OI]6300_d      3.270      0.23      -2    19
# Comp:  2           [NII]6583_d      62.17      0.23      -2    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1       188
#  comp.  1:         1        20
#  comp.  2:        -2        18
# chi2/DOF: 1.853; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.48      0.18       1    20
# Comp:  1                Halpha      229.2      0.18       1    20
# Comp:  2             [SII]6716      28.57      0.18      -2    18
# Comp:  2             [SII]6731      19.60      0.18      -2    18
# Comp:  2              HeII4687      0.000      0.18      -2    18
# Comp:  2               HeI5876      7.849      0.18      -2    18
# Comp:  2          [OIII]5007_d      66.96      0.23      -2    18
# Comp:  2            [OI]6300_d      3.357      0.23      -2    18
# Comp:  2           [NII]6583_d      61.31      0.23      -2    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135       108
#  comp.  1:         1        24
#  comp.  2:        -6        27
# chi2/DOF: 2.908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.97      0.19       1    24
# Comp:  1                Halpha      233.0      0.19       1    24
# Comp:  2             [SII]6716      28.96      0.19      -6    27
# Comp:  2             [SII]6731      19.85      0.19      -6    27
# Comp:  2              HeII4687    0.06181      0.19      -6    27
# Comp:  2               HeI5876      7.428      0.19      -6    27
# Comp:  2          [OIII]5007_d      70.46      0.24      -6    27
# Comp:  2            [OI]6300_d      3.719      0.24      -6    27
# Comp:  2           [NII]6583_d      61.98      0.24      -6    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -209         1
#  comp.  1:        -0        28
#  comp.  2:        -6        30
# chi2/DOF: 2.615; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.35      0.19      -0    28
# Comp:  1                Halpha      235.7      0.19      -0    28
# Comp:  2             [SII]6716      30.88      0.19      -6    30
# Comp:  2             [SII]6731      20.33      0.19      -6    30
# Comp:  2              HeII4687    0.04318      0.19      -6    30
# Comp:  2               HeI5876      8.172      0.19      -6    30
# Comp:  2          [OIII]5007_d      72.22      0.24      -6    30
# Comp:  2            [OI]6300_d      3.645      0.24      -6    30
# Comp:  2           [NII]6583_d      63.87      0.24      -6    30
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([5.54326916, 2.9026061 , 1.00414888, 0.72178403, 0.02537431,
#        0.55942733, 2.5258512 , 0.26442537, 1.86990286])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([5.90727316e+01, 3.18538654e+02, 4.14744493e+01, 2.80257315e+01,
#        7.60026517e-03, 9.81500929e+00, 7.40729817e+01, 4.45690125e+00,
#        8.67829183e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta   4.533215    0.425388
# 1        Halpha  24.444514    0.222745
# 2     [SII]6716   3.182731    0.077058
# 3     [SII]6731   2.150682    0.055389
# 4      HeII4687   0.000583    0.001947
# 5       HeI5876   0.753199    0.042930
# 6  [OIII]5007_d   5.684328    0.193833
# 7    [OI]6300_d   0.342021    0.020292
# 8   [NII]6583_d   6.659682    0.143496
#           Name       Flux  Error_flux
# 0        Hbeta   4.533215    0.425388
# 1       Halpha  24.444514    0.222745
# 2    [SII]6716   3.182731    0.077058
# 3    [SII]6731   2.150682    0.055389
# 4     HeII4687   0.000583    0.001947
# 5      HeI5876   0.753199    0.042930
# 6   [OIII]4959   1.421082    0.193833
# 7   [OIII]5007   4.263246    0.193833
# 8     [OI]6300   0.256515    0.020292
# 9     [OI]6364   0.085505    0.020292
# 10   [NII]6548   1.664921    0.143496
# 11   [NII]6583   4.994762    0.143496

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0767395542809325
