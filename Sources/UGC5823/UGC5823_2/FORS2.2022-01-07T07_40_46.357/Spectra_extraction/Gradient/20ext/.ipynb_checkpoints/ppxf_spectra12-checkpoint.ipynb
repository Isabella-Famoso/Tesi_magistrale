# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_12.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_12']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.07357068 0.07485111 0.06903321 ... 0.04892692 0.05788156 0.05400484] [0.0061128 0.0061128 0.0061128 ... 0.0061128 0.0061128 0.0061128]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        25
# chi2/DOF: 0.007073; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        33
# chi2/DOF: 0.004776; DOF: 1905; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-58.48853609,  32.77066181])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        19
#  comp.  1:       -82        22
#  comp.  2:       -82        27
# chi2/DOF: 1.200; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.06      0.19     -82    22
# Comp:  1                Halpha      95.62      0.19     -82    22
# Comp:  2             [SII]6716      14.04      0.20     -82    27
# Comp:  2             [SII]6731      9.781      0.20     -82    27
# Comp:  2              HeII4687      0.000      0.20     -82    27
# Comp:  2               HeI5876      3.872      0.20     -82    27
# Comp:  2          [OIII]5007_d      38.72      0.25     -82    27
# Comp:  2            [OI]6300_d      1.876      0.25     -82    27
# Comp:  2           [NII]6583_d      27.89      0.25     -82    27
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  125.4; gas flux:     27 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  456.9; gas flux:    131 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  65.89; gas flux:     20 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  44.06; gas flux:     14 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  18.07; gas flux:      5 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:    133; gas flux:     40 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  6.186; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  97.13; gas flux:     38 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        49
#  comp.  1:       -83        25
#  comp.  2:       -83        21
# chi2/DOF: 1.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.05      0.20     -83    25
# Comp:  1                Halpha      95.87      0.20     -83    25
# Comp:  2             [SII]6716      13.88      0.19     -83    21
# Comp:  2             [SII]6731      10.02      0.19     -83    21
# Comp:  2              HeII4687    0.05111      0.19     -83    21
# Comp:  2               HeI5876      3.765      0.19     -83    21
# Comp:  2          [OIII]5007_d      37.98      0.24     -83    21
# Comp:  2            [OI]6300_d      1.545      0.24     -83    21
# Comp:  2           [NII]6583_d      27.40      0.24     -83    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112         2
#  comp.  1:       -81        25
#  comp.  2:       -82        28
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.04      0.20     -81    25
# Comp:  1                Halpha      95.88      0.20     -81    25
# Comp:  2             [SII]6716      14.33      0.20     -82    28
# Comp:  2             [SII]6731      9.513      0.20     -82    28
# Comp:  2              HeII4687      0.000      0.20     -82    28
# Comp:  2               HeI5876      3.979      0.20     -82    28
# Comp:  2          [OIII]5007_d      38.07      0.25     -82    28
# Comp:  2            [OI]6300_d      1.971      0.25     -82    28
# Comp:  2           [NII]6583_d      27.98      0.25     -82    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        53
#  comp.  1:       -83        20
#  comp.  2:       -80        29
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.77      0.19     -83    20
# Comp:  1                Halpha      95.48      0.19     -83    20
# Comp:  2             [SII]6716      13.67      0.20     -80    29
# Comp:  2             [SII]6731      10.25      0.20     -80    29
# Comp:  2              HeII4687    0.08385      0.20     -80    29
# Comp:  2               HeI5876      3.646      0.20     -80    29
# Comp:  2          [OIII]5007_d      36.97      0.25     -80    29
# Comp:  2            [OI]6300_d      1.797      0.25     -80    29
# Comp:  2           [NII]6583_d      27.62      0.25     -80    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        46
#  comp.  1:       -82        19
#  comp.  2:       -84        17
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.27      0.19     -82    19
# Comp:  1                Halpha      93.89      0.19     -82    19
# Comp:  2             [SII]6716      13.53      0.19     -84    17
# Comp:  2             [SII]6731      9.550      0.19     -84    17
# Comp:  2              HeII4687      0.000      0.19     -84    17
# Comp:  2               HeI5876      3.657      0.19     -84    17
# Comp:  2          [OIII]5007_d      37.39      0.24     -84    17
# Comp:  2            [OI]6300_d      1.644      0.24     -84    17
# Comp:  2           [NII]6583_d      26.98      0.24     -84    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        28
#  comp.  1:       -82        23
#  comp.  2:       -83        22
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.13      0.19     -82    23
# Comp:  1                Halpha      95.24      0.19     -82    23
# Comp:  2             [SII]6716      14.43      0.19     -83    22
# Comp:  2             [SII]6731      9.277      0.19     -83    22
# Comp:  2              HeII4687      0.000      0.19     -83    22
# Comp:  2               HeI5876      3.629      0.19     -83    22
# Comp:  2          [OIII]5007_d      39.85      0.25     -83    22
# Comp:  2            [OI]6300_d      1.884      0.25     -83    22
# Comp:  2           [NII]6583_d      27.81      0.25     -83    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        59
#  comp.  1:       -82        15
#  comp.  2:       -81        32
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.47      0.19     -82    15
# Comp:  1                Halpha      94.56      0.19     -82    15
# Comp:  2             [SII]6716      13.86      0.20     -81    32
# Comp:  2             [SII]6731      10.02      0.20     -81    32
# Comp:  2              HeII4687      0.000      0.20     -81    32
# Comp:  2               HeI5876      3.994      0.20     -81    32
# Comp:  2          [OIII]5007_d      37.70      0.25     -81    32
# Comp:  2            [OI]6300_d      1.861      0.25     -81    32
# Comp:  2           [NII]6583_d      28.70      0.25     -81    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -82        18
#  comp.  2:       -86        28
# chi2/DOF: 1.133; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.99      0.19     -82    18
# Comp:  1                Halpha      94.11      0.19     -82    18
# Comp:  2             [SII]6716      13.70      0.20     -86    28
# Comp:  2             [SII]6731      10.06      0.20     -86    28
# Comp:  2              HeII4687      0.000      0.20     -86    28
# Comp:  2               HeI5876      4.066      0.20     -86    28
# Comp:  2          [OIII]5007_d      39.95      0.25     -86    28
# Comp:  2            [OI]6300_d      1.946      0.25     -86    28
# Comp:  2           [NII]6583_d      27.90      0.25     -86    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        54
#  comp.  1:       -82        24
#  comp.  2:       -82        33
# chi2/DOF: 0.9408; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.04      0.20     -82    24
# Comp:  1                Halpha      95.45      0.20     -82    24
# Comp:  2             [SII]6716      13.87      0.20     -82    33
# Comp:  2             [SII]6731      9.905      0.20     -82    33
# Comp:  2              HeII4687     0.1125      0.20     -82    33
# Comp:  2               HeI5876      3.721      0.20     -82    33
# Comp:  2          [OIII]5007_d      38.13      0.25     -82    33
# Comp:  2            [OI]6300_d      2.212      0.25     -82    33
# Comp:  2           [NII]6583_d      28.01      0.25     -82    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        44
#  comp.  1:       -82        19
#  comp.  2:       -81        25
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.90      0.19     -82    19
# Comp:  1                Halpha      94.31      0.19     -82    19
# Comp:  2             [SII]6716      14.15      0.20     -81    25
# Comp:  2             [SII]6731      9.694      0.20     -81    25
# Comp:  2              HeII4687    0.06627      0.20     -81    25
# Comp:  2               HeI5876      3.794      0.20     -81    25
# Comp:  2          [OIII]5007_d      39.22      0.25     -81    25
# Comp:  2            [OI]6300_d      1.905      0.25     -81    25
# Comp:  2           [NII]6583_d      27.88      0.25     -81    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -82        23
#  comp.  2:       -83        28
# chi2/DOF: 1.170; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.72      0.19     -82    23
# Comp:  1                Halpha      95.08      0.19     -82    23
# Comp:  2             [SII]6716      14.20      0.20     -83    28
# Comp:  2             [SII]6731      9.714      0.20     -83    28
# Comp:  2              HeII4687      0.000      0.20     -83    28
# Comp:  2               HeI5876      3.922      0.20     -83    28
# Comp:  2          [OIII]5007_d      37.93      0.25     -83    28
# Comp:  2            [OI]6300_d      1.928      0.25     -83    28
# Comp:  2           [NII]6583_d      28.02      0.25     -83    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105         1
#  comp.  1:       -83        21
#  comp.  2:       -80        13
# chi2/DOF: 1.005; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.80      0.19     -83    21
# Comp:  1                Halpha      96.41      0.19     -83    21
# Comp:  2             [SII]6716      13.32      0.19     -80    13
# Comp:  2             [SII]6731      9.172      0.19     -80    13
# Comp:  2              HeII4687    0.09359      0.19     -80    13
# Comp:  2               HeI5876      4.151      0.19     -80    13
# Comp:  2          [OIII]5007_d      36.37      0.24     -80    13
# Comp:  2            [OI]6300_d      1.918      0.24     -80    13
# Comp:  2           [NII]6583_d      27.16      0.24     -80    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -84        23
#  comp.  2:       -84        29
# chi2/DOF: 1.003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.51      0.19     -84    23
# Comp:  1                Halpha      96.20      0.19     -84    23
# Comp:  2             [SII]6716      13.94      0.20     -84    29
# Comp:  2             [SII]6731      9.956      0.20     -84    29
# Comp:  2              HeII4687      0.000      0.20     -84    29
# Comp:  2               HeI5876      4.224      0.20     -84    29
# Comp:  2          [OIII]5007_d      37.33      0.25     -84    29
# Comp:  2            [OI]6300_d      1.880      0.25     -84    29
# Comp:  2           [NII]6583_d      27.76      0.25     -84    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        31
#  comp.  1:       -83        21
#  comp.  2:       -85        26
# chi2/DOF: 1.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.25      0.19     -83    21
# Comp:  1                Halpha      95.07      0.19     -83    21
# Comp:  2             [SII]6716      14.76      0.20     -85    26
# Comp:  2             [SII]6731      10.14      0.20     -85    26
# Comp:  2              HeII4687    0.01697      0.20     -85    26
# Comp:  2               HeI5876      3.757      0.20     -85    26
# Comp:  2          [OIII]5007_d      40.01      0.25     -85    26
# Comp:  2            [OI]6300_d      1.743      0.25     -85    26
# Comp:  2           [NII]6583_d      27.74      0.25     -85    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        47
#  comp.  1:       -83        22
#  comp.  2:       -82        26
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.86      0.19     -83    22
# Comp:  1                Halpha      94.26      0.19     -83    22
# Comp:  2             [SII]6716      14.73      0.20     -82    26
# Comp:  2             [SII]6731      10.08      0.20     -82    26
# Comp:  2              HeII4687      0.000      0.20     -82    26
# Comp:  2               HeI5876      4.133      0.20     -82    26
# Comp:  2          [OIII]5007_d      39.64      0.25     -82    26
# Comp:  2            [OI]6300_d      1.851      0.25     -82    26
# Comp:  2           [NII]6583_d      27.73      0.25     -82    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        55
#  comp.  1:       -81        20
#  comp.  2:       -82        27
# chi2/DOF: 0.9257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.23      0.19     -81    20
# Comp:  1                Halpha      95.81      0.19     -81    20
# Comp:  2             [SII]6716      14.42      0.20     -82    27
# Comp:  2             [SII]6731      9.177      0.20     -82    27
# Comp:  2              HeII4687      0.000      0.20     -82    27
# Comp:  2               HeI5876      4.182      0.20     -82    27
# Comp:  2          [OIII]5007_d      39.09      0.25     -82    27
# Comp:  2            [OI]6300_d      1.907      0.25     -82    27
# Comp:  2           [NII]6583_d      27.51      0.25     -82    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -82        18
#  comp.  2:       -81        36
# chi2/DOF: 0.9716; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.31      0.19     -82    18
# Comp:  1                Halpha      94.00      0.19     -82    18
# Comp:  2             [SII]6716      14.61      0.20     -81    36
# Comp:  2             [SII]6731      9.895      0.20     -81    36
# Comp:  2              HeII4687     0.1556      0.20     -81    36
# Comp:  2               HeI5876      3.727      0.20     -81    36
# Comp:  2          [OIII]5007_d      40.73      0.25     -81    36
# Comp:  2            [OI]6300_d      1.834      0.25     -81    36
# Comp:  2           [NII]6583_d      28.53      0.25     -81    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87         1
#  comp.  1:       -81        21
#  comp.  2:       -81        10
# chi2/DOF: 0.9479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.80      0.19     -81    21
# Comp:  1                Halpha      95.80      0.19     -81    21
# Comp:  2             [SII]6716      13.89      0.19     -81    10
# Comp:  2             [SII]6731      9.389      0.19     -81    10
# Comp:  2              HeII4687      0.000      0.19     -81    10
# Comp:  2               HeI5876      3.632      0.19     -81    10
# Comp:  2          [OIII]5007_d      36.60      0.24     -81    10
# Comp:  2            [OI]6300_d      1.779      0.24     -81    10
# Comp:  2           [NII]6583_d      27.30      0.24     -81    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         6
#  comp.  1:       -82        27
#  comp.  2:       -81        33
# chi2/DOF: 0.9381; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.75      0.20     -82    27
# Comp:  1                Halpha      96.88      0.20     -82    27
# Comp:  2             [SII]6716      14.44      0.20     -81    33
# Comp:  2             [SII]6731      9.233      0.20     -81    33
# Comp:  2              HeII4687     0.1219      0.20     -81    33
# Comp:  2               HeI5876      4.013      0.20     -81    33
# Comp:  2          [OIII]5007_d      40.06      0.25     -81    33
# Comp:  2            [OI]6300_d      1.734      0.25     -81    33
# Comp:  2           [NII]6583_d      28.39      0.25     -81    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:       -83        25
#  comp.  2:       -78        14
# chi2/DOF: 0.9021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.83      0.20     -83    25
# Comp:  1                Halpha      95.73      0.20     -83    25
# Comp:  2             [SII]6716      14.05      0.19     -78    14
# Comp:  2             [SII]6731      9.455      0.19     -78    14
# Comp:  2              HeII4687    0.05557      0.19     -78    14
# Comp:  2               HeI5876      3.698      0.19     -78    14
# Comp:  2          [OIII]5007_d      37.46      0.24     -78    14
# Comp:  2            [OI]6300_d      2.195      0.24     -78    14
# Comp:  2           [NII]6583_d      26.52      0.24     -78    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       -83        26
#  comp.  2:       -85        35
# chi2/DOF: 0.9093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.98      0.20     -83    26
# Comp:  1                Halpha      96.38      0.20     -83    26
# Comp:  2             [SII]6716      14.00      0.20     -85    35
# Comp:  2             [SII]6731      10.66      0.20     -85    35
# Comp:  2              HeII4687    0.06854      0.20     -85    35
# Comp:  2               HeI5876      3.516      0.20     -85    35
# Comp:  2          [OIII]5007_d      39.98      0.25     -85    35
# Comp:  2            [OI]6300_d      2.008      0.25     -85    35
# Comp:  2           [NII]6583_d      28.89      0.25     -85    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        94
#  comp.  1:       -82        19
#  comp.  2:       -83        35
# chi2/DOF: 0.9177; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.51      0.19     -82    19
# Comp:  1                Halpha      94.05      0.19     -82    19
# Comp:  2             [SII]6716      13.94      0.20     -83    35
# Comp:  2             [SII]6731      10.46      0.20     -83    35
# Comp:  2              HeII4687    0.03525      0.20     -83    35
# Comp:  2               HeI5876      4.316      0.20     -83    35
# Comp:  2          [OIII]5007_d      40.43      0.25     -83    35
# Comp:  2            [OI]6300_d      2.193      0.25     -83    35
# Comp:  2           [NII]6583_d      28.61      0.25     -83    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        33
#  comp.  1:       -82        24
#  comp.  2:       -85        27
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.25      0.19     -82    24
# Comp:  1                Halpha      95.61      0.19     -82    24
# Comp:  2             [SII]6716      14.26      0.20     -85    27
# Comp:  2             [SII]6731      9.669      0.20     -85    27
# Comp:  2              HeII4687      0.000      0.20     -85    27
# Comp:  2               HeI5876      4.083      0.20     -85    27
# Comp:  2          [OIII]5007_d      39.38      0.25     -85    27
# Comp:  2            [OI]6300_d      1.885      0.25     -85    27
# Comp:  2           [NII]6583_d      28.10      0.25     -85    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114        28
#  comp.  1:       -84        20
#  comp.  2:       -83        35
# chi2/DOF: 1.136; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.32      0.19     -84    20
# Comp:  1                Halpha      95.57      0.19     -84    20
# Comp:  2             [SII]6716      14.54      0.20     -83    35
# Comp:  2             [SII]6731      10.16      0.20     -83    35
# Comp:  2              HeII4687    0.06350      0.20     -83    35
# Comp:  2               HeI5876      3.659      0.20     -83    35
# Comp:  2          [OIII]5007_d      39.53      0.25     -83    35
# Comp:  2            [OI]6300_d      1.961      0.25     -83    35
# Comp:  2           [NII]6583_d      28.40      0.25     -83    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        37
#  comp.  1:       -83        20
#  comp.  2:       -84        30
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.13      0.19     -83    20
# Comp:  1                Halpha      96.27      0.19     -83    20
# Comp:  2             [SII]6716      14.33      0.20     -84    30
# Comp:  2             [SII]6731      10.25      0.20     -84    30
# Comp:  2              HeII4687     0.1683      0.20     -84    30
# Comp:  2               HeI5876      4.045      0.20     -84    30
# Comp:  2          [OIII]5007_d      40.72      0.25     -84    30
# Comp:  2            [OI]6300_d      1.993      0.25     -84    30
# Comp:  2           [NII]6583_d      27.94      0.25     -84    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -82        22
#  comp.  2:       -84        37
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.91      0.19     -82    22
# Comp:  1                Halpha      94.58      0.19     -82    22
# Comp:  2             [SII]6716      15.05      0.20     -84    37
# Comp:  2             [SII]6731      10.11      0.20     -84    37
# Comp:  2              HeII4687      0.000      0.20     -84    37
# Comp:  2               HeI5876      3.931      0.20     -84    37
# Comp:  2          [OIII]5007_d      41.44      0.26     -84    37
# Comp:  2            [OI]6300_d      1.794      0.26     -84    37
# Comp:  2           [NII]6583_d      28.94      0.26     -84    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        24
#  comp.  1:       -82        19
#  comp.  2:       -82        32
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.83      0.19     -82    19
# Comp:  1                Halpha      95.00      0.19     -82    19
# Comp:  2             [SII]6716      13.90      0.20     -82    32
# Comp:  2             [SII]6731      10.27      0.20     -82    32
# Comp:  2              HeII4687     0.1049      0.20     -82    32
# Comp:  2               HeI5876      4.408      0.20     -82    32
# Comp:  2          [OIII]5007_d      41.36      0.25     -82    32
# Comp:  2            [OI]6300_d      1.866      0.25     -82    32
# Comp:  2           [NII]6583_d      27.91      0.25     -82    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        42
#  comp.  1:       -84        24
#  comp.  2:       -84        28
# chi2/DOF: 1.071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.98      0.20     -84    24
# Comp:  1                Halpha      97.15      0.20     -84    24
# Comp:  2             [SII]6716      14.17      0.20     -84    28
# Comp:  2             [SII]6731      9.189      0.20     -84    28
# Comp:  2              HeII4687     0.2753      0.20     -84    28
# Comp:  2               HeI5876      3.831      0.20     -84    28
# Comp:  2          [OIII]5007_d      40.75      0.25     -84    28
# Comp:  2            [OI]6300_d      1.931      0.25     -84    28
# Comp:  2           [NII]6583_d      28.15      0.25     -84    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       -83        17
#  comp.  2:       -84        30
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.88      0.19     -83    17
# Comp:  1                Halpha      95.78      0.19     -83    17
# Comp:  2             [SII]6716      13.67      0.20     -84    30
# Comp:  2             [SII]6731      10.20      0.20     -84    30
# Comp:  2              HeII4687      0.000      0.20     -84    30
# Comp:  2               HeI5876      3.931      0.20     -84    30
# Comp:  2          [OIII]5007_d      38.64      0.25     -84    30
# Comp:  2            [OI]6300_d      2.037      0.25     -84    30
# Comp:  2           [NII]6583_d      28.44      0.25     -84    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -84        20
#  comp.  2:       -81        25
# chi2/DOF: 0.9609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.64      0.19     -84    20
# Comp:  1                Halpha      95.53      0.19     -84    20
# Comp:  2             [SII]6716      13.75      0.20     -81    25
# Comp:  2             [SII]6731      10.13      0.20     -81    25
# Comp:  2              HeII4687      0.000      0.20     -81    25
# Comp:  2               HeI5876      3.758      0.20     -81    25
# Comp:  2          [OIII]5007_d      38.16      0.25     -81    25
# Comp:  2            [OI]6300_d      1.875      0.25     -81    25
# Comp:  2           [NII]6583_d      27.80      0.25     -81    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        66
#  comp.  1:       -80        20
#  comp.  2:       -82        19
# chi2/DOF: 0.9824; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.22      0.19     -80    20
# Comp:  1                Halpha      95.27      0.19     -80    20
# Comp:  2             [SII]6716      14.26      0.19     -82    19
# Comp:  2             [SII]6731      9.936      0.19     -82    19
# Comp:  2              HeII4687    0.05895      0.19     -82    19
# Comp:  2               HeI5876      3.697      0.19     -82    19
# Comp:  2          [OIII]5007_d      39.07      0.24     -82    19
# Comp:  2            [OI]6300_d      1.834      0.24     -82    19
# Comp:  2           [NII]6583_d      28.05      0.24     -82    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         1
#  comp.  1:       -81        23
#  comp.  2:       -83        32
# chi2/DOF: 1.166; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.81      0.19     -81    23
# Comp:  1                Halpha      94.81      0.19     -81    23
# Comp:  2             [SII]6716      14.75      0.20     -83    32
# Comp:  2             [SII]6731      10.29      0.20     -83    32
# Comp:  2              HeII4687    0.05600      0.20     -83    32
# Comp:  2               HeI5876      3.727      0.20     -83    32
# Comp:  2          [OIII]5007_d      39.38      0.25     -83    32
# Comp:  2            [OI]6300_d      1.806      0.25     -83    32
# Comp:  2           [NII]6583_d      28.37      0.25     -83    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -82        21
#  comp.  2:       -79        23
# chi2/DOF: 0.9563; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.54      0.19     -82    21
# Comp:  1                Halpha      94.86      0.19     -82    21
# Comp:  2             [SII]6716      14.27      0.19     -79    23
# Comp:  2             [SII]6731      9.942      0.19     -79    23
# Comp:  2              HeII4687    0.05031      0.19     -79    23
# Comp:  2               HeI5876      3.750      0.19     -79    23
# Comp:  2          [OIII]5007_d      39.90      0.25     -79    23
# Comp:  2            [OI]6300_d      1.802      0.25     -79    23
# Comp:  2           [NII]6583_d      27.35      0.25     -79    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        53
#  comp.  1:       -82        16
#  comp.  2:       -80        25
# chi2/DOF: 0.9802; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.98      0.19     -82    16
# Comp:  1                Halpha      93.23      0.19     -82    16
# Comp:  2             [SII]6716      14.47      0.20     -80    25
# Comp:  2             [SII]6731      9.059      0.20     -80    25
# Comp:  2              HeII4687      0.000      0.20     -80    25
# Comp:  2               HeI5876      4.094      0.20     -80    25
# Comp:  2          [OIII]5007_d      40.06      0.25     -80    25
# Comp:  2            [OI]6300_d      1.809      0.25     -80    25
# Comp:  2           [NII]6583_d      28.12      0.25     -80    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       -80        21
#  comp.  2:       -79        27
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.83      0.19     -80    21
# Comp:  1                Halpha      95.71      0.19     -80    21
# Comp:  2             [SII]6716      14.58      0.20     -79    27
# Comp:  2             [SII]6731      9.773      0.20     -79    27
# Comp:  2              HeII4687    0.05672      0.20     -79    27
# Comp:  2               HeI5876      3.665      0.20     -79    27
# Comp:  2          [OIII]5007_d      37.60      0.25     -79    27
# Comp:  2            [OI]6300_d      1.753      0.25     -79    27
# Comp:  2           [NII]6583_d      27.64      0.25     -79    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        80
#  comp.  1:       -82        23
#  comp.  2:       -82        27
# chi2/DOF: 1.175; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.27      0.19     -82    23
# Comp:  1                Halpha      96.22      0.19     -82    23
# Comp:  2             [SII]6716      14.48      0.20     -82    27
# Comp:  2             [SII]6731      9.422      0.20     -82    27
# Comp:  2              HeII4687      0.000      0.20     -82    27
# Comp:  2               HeI5876      4.160      0.20     -82    27
# Comp:  2          [OIII]5007_d      37.66      0.25     -82    27
# Comp:  2            [OI]6300_d      1.880      0.25     -82    27
# Comp:  2           [NII]6583_d      27.63      0.25     -82    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        26
#  comp.  1:       -81        25
#  comp.  2:       -82        24
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.31      0.20     -81    25
# Comp:  1                Halpha      96.39      0.20     -81    25
# Comp:  2             [SII]6716      14.44      0.20     -82    24
# Comp:  2             [SII]6731      10.34      0.20     -82    24
# Comp:  2              HeII4687     0.2530      0.20     -82    24
# Comp:  2               HeI5876      4.002      0.20     -82    24
# Comp:  2          [OIII]5007_d      39.39      0.25     -82    24
# Comp:  2            [OI]6300_d      2.153      0.25     -82    24
# Comp:  2           [NII]6583_d      27.84      0.25     -82    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102        37
#  comp.  1:       -83        23
#  comp.  2:       -78        24
# chi2/DOF: 0.9446; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.61      0.19     -83    23
# Comp:  1                Halpha      96.70      0.19     -83    23
# Comp:  2             [SII]6716      13.62      0.20     -78    24
# Comp:  2             [SII]6731      9.412      0.20     -78    24
# Comp:  2              HeII4687     0.2148      0.20     -78    24
# Comp:  2               HeI5876      3.768      0.20     -78    24
# Comp:  2          [OIII]5007_d      38.16      0.25     -78    24
# Comp:  2            [OI]6300_d      1.866      0.25     -78    24
# Comp:  2           [NII]6583_d      27.57      0.25     -78    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        30
#  comp.  1:       -81        24
#  comp.  2:       -84        35
# chi2/DOF: 0.9515; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.18      0.20     -81    24
# Comp:  1                Halpha      95.01      0.20     -81    24
# Comp:  2             [SII]6716      14.43      0.20     -84    35
# Comp:  2             [SII]6731      10.11      0.20     -84    35
# Comp:  2              HeII4687    0.04283      0.20     -84    35
# Comp:  2               HeI5876      3.898      0.20     -84    35
# Comp:  2          [OIII]5007_d      41.15      0.25     -84    35
# Comp:  2            [OI]6300_d      2.035      0.25     -84    35
# Comp:  2           [NII]6583_d      29.07      0.25     -84    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98         1
#  comp.  1:       -81        21
#  comp.  2:       -79        26
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.40      0.19     -81    21
# Comp:  1                Halpha      94.90      0.19     -81    21
# Comp:  2             [SII]6716      14.20      0.20     -79    26
# Comp:  2             [SII]6731      9.450      0.20     -79    26
# Comp:  2              HeII4687      0.000      0.20     -79    26
# Comp:  2               HeI5876      4.143      0.20     -79    26
# Comp:  2          [OIII]5007_d      37.46      0.25     -79    26
# Comp:  2            [OI]6300_d      1.586      0.25     -79    26
# Comp:  2           [NII]6583_d      27.73      0.25     -79    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -82        24
#  comp.  2:       -83        34
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.27      0.19     -82    24
# Comp:  1                Halpha      94.73      0.19     -82    24
# Comp:  2             [SII]6716      14.73      0.20     -83    34
# Comp:  2             [SII]6731      9.665      0.20     -83    34
# Comp:  2              HeII4687    0.05472      0.20     -83    34
# Comp:  2               HeI5876      4.024      0.20     -83    34
# Comp:  2          [OIII]5007_d      40.68      0.25     -83    34
# Comp:  2            [OI]6300_d      1.730      0.25     -83    34
# Comp:  2           [NII]6583_d      28.61      0.25     -83    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       -83        23
#  comp.  2:       -80        29
# chi2/DOF: 0.9157; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.36      0.19     -83    23
# Comp:  1                Halpha      96.52      0.19     -83    23
# Comp:  2             [SII]6716      13.75      0.20     -80    29
# Comp:  2             [SII]6731      9.917      0.20     -80    29
# Comp:  2              HeII4687     0.2916      0.20     -80    29
# Comp:  2               HeI5876      3.914      0.20     -80    29
# Comp:  2          [OIII]5007_d      36.77      0.25     -80    29
# Comp:  2            [OI]6300_d      1.863      0.25     -80    29
# Comp:  2           [NII]6583_d      27.65      0.25     -80    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        52
#  comp.  1:       -83        21
#  comp.  2:       -81        32
# chi2/DOF: 0.9050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.87      0.19     -83    21
# Comp:  1                Halpha      97.03      0.19     -83    21
# Comp:  2             [SII]6716      13.72      0.20     -81    32
# Comp:  2             [SII]6731      9.967      0.20     -81    32
# Comp:  2              HeII4687      0.000      0.20     -81    32
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.19      0.19     -81    24
# Comp:  1                Halpha      94.87      0.19     -81    24
# Comp:  2             [SII]6716      13.15      0.19     -80    14
# Comp:  2             [SII]6731      9.792      0.19     -80    14
# Comp:  2              HeII4687      0.000      0.19     -80    14
# Comp:  2               HeI5876      3.735      0.19     -80    14
# Comp:  2          [OIII]5007_d      38.47      0.24     -80    14
# Comp:  2            [OI]6300_d      1.930      0.24     -80    14
# Comp:  2           [NII]6583_d      27.03      0.24     -80    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -83        25
#  comp.  2:       -77        28
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.20      0.20     -83    25
# Comp:  1                Halpha      96.33      0.20     -83    25
# Comp:  2             [SII]6716      14.02      0.20     -77    28
# Comp:  2             [SII]6731      9.745      0.20     -77    28
# Comp:  2              HeII4687      0.000      0.20     -77    28
# Comp:  2               HeI5876      3.778      0.20     -77    28
# Comp:  2          [OIII]5007_d      38.63      0.25     -77    28
# Comp:  2            [OI]6300_d      2.038      0.25     -77    28
# Comp:  2           [NII]6583_d      27.89      0.25     -77    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        18
#  comp.  1:       -82        27
#  comp.  2:       -82        32
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.80      0.20     -82    27
# Comp:  1                Halpha      97.48      0.20     -82    27
# Comp:  2             [SII]6716      13.53      0.20     -82    32
# Comp:  2             [SII]6731      10.05      0.20     -82    32
# Comp:  2              HeII4687      0.000      0.20     -82    32
# Comp:  2               HeI5876      4.381      0.20     -82    32
# Comp:  2          [OIII]5007_d      39.37      0.25     -82    32
# Comp:  2            [OI]6300_d      1.935      0.25     -82    32
# Comp:  2           [NII]6583_d      28.10      0.25     -82    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69       106
#  comp.  1:       -82        25
#  comp.  2:       -83        17
# chi2/DOF: 1.146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.32      0.20     -82    25
# Comp:  1                Halpha      96.21      0.20     -82    25
# Comp:  2             [SII]6716      14.13      0.19     -83    17
# Comp:  2             [SII]6731      9.763      0.19     -83    17
# Comp:  2              HeII4687     0.1773      0.19     -83    17
# Comp:  2               HeI5876      3.743      0.19     -83    17
# Comp:  2          [OIII]5007_d      37.09      0.24     -83    17
# Comp:  2            [OI]6300_d      1.853      0.24     -83    17
# Comp:  2           [NII]6583_d      27.09      0.24     -83    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -83        16
#  comp.  2:       -83        24
# chi2/DOF: 1.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.36      0.19     -83    16
# Comp:  1                Halpha      95.06      0.19     -83    16
# Comp:  2             [SII]6716      13.68      0.20     -83    24
# Comp:  2             [SII]6731      10.32      0.20     -83    24
# Comp:  2              HeII4687      0.000      0.20     -83    24
# Comp:  2               HeI5876      3.599      0.20     -83    24
# Comp:  2          [OIII]5007_d      38.00      0.25     -83    24
# Comp:  2            [OI]6300_d      1.760      0.25     -83    24
# Comp:  2           [NII]6583_d      27.68      0.25     -83    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        60
#  comp.  1:       -82        18
#  comp.  2:       -82        17
# chi2/DOF: 0.9321; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.32      0.19     -82    18
# Comp:  1                Halpha      95.20      0.19     -82    18
# Comp:  2             [SII]6716      13.19      0.19     -82    17
# Comp:  2             [SII]6731      9.835      0.19     -82    17
# Comp:  2              HeII4687      0.000      0.19     -82    17
# Comp:  2               HeI5876      3.806      0.19     -82    17
# Comp:  2          [OIII]5007_d      36.00      0.24     -82    17
# Comp:  2            [OI]6300_d      1.544      0.24     -82    17
# Comp:  2           [NII]6583_d      27.48      0.24     -82    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        27
#  comp.  1:       -81        22
#  comp.  2:       -79        29
# chi2/DOF: 1.155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.10      0.19     -81    22
# Comp:  1                Halpha      95.28      0.19     -81    22
# Comp:  2             [SII]6716      13.69      0.20     -79    29
# Comp:  2             [SII]6731      9.733      0.20     -79    29
# Comp:  2              HeII4687    0.02008      0.20     -79    29
# Comp:  2               HeI5876      4.140      0.20     -79    29
# Comp:  2          [OIII]5007_d      37.60      0.25     -79    29
# Comp:  2            [OI]6300_d      1.780      0.25     -79    29
# Comp:  2           [NII]6583_d      27.98      0.25     -79    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        19
#  comp.  1:       -83        20
#  comp.  2:       -86        25
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.81      0.19     -83    20
# Comp:  1                Halpha      96.51      0.19     -83    20
# Comp:  2             [SII]6716      14.24      0.20     -86    25
# Comp:  2             [SII]6731      9.641      0.20     -86    25
# Comp:  2              HeII4687    0.02140      0.20     -86    25
# Comp:  2               HeI5876      3.998      0.20     -86    25
# Comp:  2          [OIII]5007_d      38.81      0.25     -86    25
# Comp:  2            [OI]6300_d      1.753      0.25     -86    25
# Comp:  2           [NII]6583_d      27.95      0.25     -86    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -83        22
#  comp.  2:       -82        36
# chi2/DOF: 0.9425; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.03      0.19     -83    22
# Comp:  1                Halpha      95.84      0.19     -83    22
# Comp:  2             [SII]6716      14.30      0.20     -82    36
# Comp:  2             [SII]6731      10.48      0.20     -82    36
# Comp:  2              HeII4687      0.000      0.20     -82    36
# Comp:  2               HeI5876      4.116      0.20     -82    36
# Comp:  2          [OIII]5007_d      38.45      0.25     -82    36
# Comp:  2            [OI]6300_d      1.786      0.25     -82    36
# Comp:  2           [NII]6583_d      28.38      0.25     -82    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        34
#  comp.  1:       -82        27
#  comp.  2:       -80        20
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.29      0.20     -82    27
# Comp:  1                Halpha      97.37      0.20     -82    27
# Comp:  2             [SII]6716      14.34      0.19     -80    20
# Comp:  2             [SII]6731      9.566      0.19     -80    20
# Comp:  2              HeII4687      0.000      0.19     -80    20
# Comp:  2               HeI5876      3.764      0.19     -80    20
# Comp:  2          [OIII]5007_d      36.63      0.24     -80    20
# Comp:  2            [OI]6300_d      1.962      0.24     -80    20
# Comp:  2           [NII]6583_d      26.74      0.24     -80    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -81        26
#  comp.  2:       -83        15
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.99      0.20     -81    26
# Comp:  1                Halpha      95.25      0.20     -81    26
# Comp:  2             [SII]6716      13.80      0.19     -83    15
# Comp:  2             [SII]6731      9.447      0.19     -83    15
# Comp:  2              HeII4687      0.000      0.19     -83    15
# Comp:  2               HeI5876      3.609      0.19     -83    15
# Comp:  2          [OIII]5007_d      38.30      0.24     -83    15
# Comp:  2            [OI]6300_d      1.764      0.24     -83    15
# Comp:  2           [NII]6583_d      27.01      0.24     -83    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        38
#  comp.  1:       -82        15
#  comp.  2:       -81        16
# chi2/DOF: 0.8932; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.16      0.19     -82    15
# Comp:  1                Halpha      93.72      0.19     -82    15
# Comp:  2             [SII]6716      13.15      0.19     -81    16
# Comp:  2             [SII]6731      9.472      0.19     -81    16
# Comp:  2              HeII4687    0.01415      0.19     -81    16
# Comp:  2               HeI5876      3.779      0.19     -81    16
# Comp:  2          [OIII]5007_d      36.96      0.24     -81    16
# Comp:  2            [OI]6300_d      1.876      0.24     -81    16
# Comp:  2           [NII]6583_d      27.24      0.24     -81    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        42
#  comp.  1:       -82        23
#  comp.  2:       -84        28
# chi2/DOF: 1.132; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.34      0.19     -82    23
# Comp:  1                Halpha      96.25      0.19     -82    23
# Comp:  2             [SII]6716      13.86      0.20     -84    28
# Comp:  2             [SII]6731      9.817      0.20     -84    28
# Comp:  2              HeII4687    0.03817      0.20     -84    28
# Comp:  2               HeI5876      3.537      0.20     -84    28
# Comp:  2          [OIII]5007_d      37.15      0.25     -84    28
# Comp:  2            [OI]6300_d      2.159      0.25     -84    28
# Comp:  2           [NII]6583_d      27.54      0.25     -84    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -83        27
#  comp.  2:       -86        29
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.49      0.20     -83    27
# Comp:  1                Halpha      97.26      0.20     -83    27
# Comp:  2             [SII]6716      14.53      0.20     -86    29
# Comp:  2             [SII]6731      9.871      0.20     -86    29
# Comp:  2              HeII4687     0.2797      0.20     -86    29
# Comp:  2               HeI5876      3.917      0.20     -86    29
# Comp:  2          [OIII]5007_d      39.07      0.25     -86    29
# Comp:  2            [OI]6300_d      2.105      0.25     -86    29
# Comp:  2           [NII]6583_d      27.87      0.25     -86    29
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.83227875, 1.46688063, 0.61646006, 0.54473649, 0.07478983,
#        0.28001596, 1.47297687, 0.20915106, 0.75194403])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 27.43637509, 130.88958668,  19.66912981,  13.73082453,
#          0.        ,   4.74572929,  40.43945838,   2.46554424,
#         38.29897881])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_12_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_12", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_12_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_12_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_12_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  1.717615    0.177311
# 1        Halpha  8.194157    0.091832
# 2     [SII]6716  1.231358    0.038593
# 3     [SII]6731  0.859599    0.034102
# 4      HeII4687  0.000000    0.004682
# 5       HeI5876  0.297100    0.017530
# 6  [OIII]5007_d  2.531655    0.092214
# 7    [OI]6300_d  0.154352    0.013094
# 8   [NII]6583_d  2.397653    0.047074
#           Name      Flux  Error_flux
# 0        Hbeta  1.717615    0.177311
# 1       Halpha  8.194157    0.091832
# 2    [SII]6716  1.231358    0.038593
# 3    [SII]6731  0.859599    0.034102
# 4     HeII4687  0.000000    0.004682
# 5      HeI5876  0.297100    0.017530
# 6   [OIII]4959  0.632914    0.092214
# 7   [OIII]5007  1.898741    0.092214
# 8     [OI]6300  0.115764    0.013094
# 9     [OI]6364  0.038588    0.013094
# 10   [NII]6548  0.599413    0.047074
# 11   [NII]6583  1.798240    0.047074

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06260358539668084
