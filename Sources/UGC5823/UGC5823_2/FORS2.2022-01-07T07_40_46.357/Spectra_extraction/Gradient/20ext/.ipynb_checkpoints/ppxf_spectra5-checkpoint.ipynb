# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_5.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188  
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.05854221 0.06229243 0.05162418 ... 0.02944855 0.0360559  0.03595802] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
# chi2/DOF: 0.01241; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
# chi2/DOF: 0.007341; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-67.25744575,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         7
#  comp.  1:       -72        34
#  comp.  2:       -73        41
# chi2/DOF: 0.8745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.944      0.24     -72    34
# Comp:  1                Halpha      23.19      0.24     -72    34
# Comp:  2             [SII]6716      4.923      0.24     -73    41
# Comp:  2             [SII]6731      3.818      0.24     -73    41
# Comp:  2              HeII4687     0.5272      0.24     -73    41
# Comp:  2               HeI5876      1.062      0.24     -73    41
# Comp:  2          [OIII]5007_d      10.67      0.31     -73    41
# Comp:  2            [OI]6300_d     0.5461      0.31     -73    41
# Comp:  2           [NII]6583_d      7.263      0.31     -73    41
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:     24; gas flux:      7 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  83.97; gas flux:     32 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  17.33; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  12.67; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.889; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.809; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  28.61; gas flux:     11 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.393; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   18.8; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        42
#  comp.  1:       -72        36
#  comp.  2:       -72        35
# chi2/DOF: 0.8664; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.177      0.24     -72    36
# Comp:  1                Halpha      23.68      0.24     -72    36
# Comp:  2             [SII]6716      4.817      0.24     -72    35
# Comp:  2             [SII]6731      3.960      0.24     -72    35
# Comp:  2              HeII4687     0.5485      0.24     -72    35
# Comp:  2               HeI5876      1.110      0.24     -72    35
# Comp:  2          [OIII]5007_d      10.44      0.30     -72    35
# Comp:  2            [OI]6300_d     0.4957      0.30     -72    35
# Comp:  2           [NII]6583_d      6.977      0.30     -72    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         8
#  comp.  1:       -70        34
#  comp.  2:       -71        39
# chi2/DOF: 0.8657; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.042      0.24     -70    34
# Comp:  1                Halpha      23.23      0.24     -70    34
# Comp:  2             [SII]6716      5.140      0.24     -71    39
# Comp:  2             [SII]6731      3.541      0.24     -71    39
# Comp:  2              HeII4687     0.2261      0.24     -71    39
# Comp:  2               HeI5876      1.074      0.24     -71    39
# Comp:  2          [OIII]5007_d      10.66      0.31     -71    39
# Comp:  2            [OI]6300_d     0.6266      0.31     -71    39
# Comp:  2           [NII]6583_d      7.360      0.31     -71    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        23
#  comp.  1:       -73        34
#  comp.  2:       -71        48
# chi2/DOF: 0.8648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.384      0.24     -73    34
# Comp:  1                Halpha      23.41      0.24     -73    34
# Comp:  2             [SII]6716      4.753      0.25     -71    48
# Comp:  2             [SII]6731      4.258      0.25     -71    48
# Comp:  2              HeII4687     0.5791      0.25     -71    48
# Comp:  2               HeI5876      1.065      0.25     -71    48
# Comp:  2          [OIII]5007_d      10.64      0.31     -71    48
# Comp:  2            [OI]6300_d     0.5295      0.31     -71    48
# Comp:  2           [NII]6583_d      7.282      0.31     -71    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        29
#  comp.  1:       -71        33
#  comp.  2:       -75        35
# chi2/DOF: 0.8611; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.619      0.24     -71    33
# Comp:  1                Halpha      23.07      0.24     -71    33
# Comp:  2             [SII]6716      5.099      0.24     -75    35
# Comp:  2             [SII]6731      3.883      0.24     -75    35
# Comp:  2              HeII4687     0.4005      0.24     -75    35
# Comp:  2               HeI5876      1.035      0.24     -75    35
# Comp:  2          [OIII]5007_d      10.29      0.30     -75    35
# Comp:  2            [OI]6300_d     0.4426      0.30     -75    35
# Comp:  2           [NII]6583_d      6.972      0.30     -75    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        32
#  comp.  1:       -71        32
#  comp.  2:       -73        37
# chi2/DOF: 0.8644; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.205      0.24     -71    32
# Comp:  1                Halpha      23.07      0.24     -71    32
# Comp:  2             [SII]6716      4.896      0.24     -73    37
# Comp:  2             [SII]6731      3.547      0.24     -73    37
# Comp:  2              HeII4687     0.5334      0.24     -73    37
# Comp:  2               HeI5876      1.094      0.24     -73    37
# Comp:  2          [OIII]5007_d      10.85      0.30     -73    37
# Comp:  2            [OI]6300_d     0.4649      0.30     -73    37
# Comp:  2           [NII]6583_d      7.259      0.30     -73    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        68
#  comp.  1:       -72        31
#  comp.  2:       -69        49
# chi2/DOF: 0.8602; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.372      0.24     -72    31
# Comp:  1                Halpha      23.08      0.24     -72    31
# Comp:  2             [SII]6716      4.669      0.25     -69    49
# Comp:  2             [SII]6731      3.831      0.25     -69    49
# Comp:  2              HeII4687     0.5404      0.25     -69    49
# Comp:  2               HeI5876      1.169      0.25     -69    49
# Comp:  2          [OIII]5007_d      10.76      0.32     -69    49
# Comp:  2            [OI]6300_d     0.4178      0.32     -69    49
# Comp:  2           [NII]6583_d      7.692      0.32     -69    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -71        34
#  comp.  2:       -77        40
# chi2/DOF: 0.8652; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.156      0.24     -71    34
# Comp:  1                Halpha      23.27      0.24     -71    34
# Comp:  2             [SII]6716      5.146      0.24     -77    40
# Comp:  2             [SII]6731      4.142      0.24     -77    40
# Comp:  2              HeII4687     0.4304      0.24     -77    40
# Comp:  2               HeI5876      1.099      0.24     -77    40
# Comp:  2          [OIII]5007_d      10.63      0.31     -77    40
# Comp:  2            [OI]6300_d     0.6112      0.31     -77    40
# Comp:  2           [NII]6583_d      7.163      0.31     -77    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -71        32
#  comp.  2:       -72        44
# chi2/DOF: 0.8621; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.532      0.24     -71    32
# Comp:  1                Halpha      22.87      0.24     -71    32
# Comp:  2             [SII]6716      4.954      0.25     -72    44
# Comp:  2             [SII]6731      3.932      0.25     -72    44
# Comp:  2              HeII4687     0.7218      0.25     -72    44
# Comp:  2               HeI5876      1.106      0.25     -72    44
# Comp:  2          [OIII]5007_d      10.66      0.31     -72    44
# Comp:  2            [OI]6300_d     0.7165      0.31     -72    44
# Comp:  2           [NII]6583_d      7.238      0.31     -72    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        29
#  comp.  1:       -72        31
#  comp.  2:       -70        40
# chi2/DOF: 0.8631; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.490      0.24     -72    31
# Comp:  1                Halpha      22.92      0.24     -72    31
# Comp:  2             [SII]6716      4.948      0.24     -70    40
# Comp:  2             [SII]6731      3.758      0.24     -70    40
# Comp:  2              HeII4687     0.6571      0.24     -70    40
# Comp:  2               HeI5876      1.153      0.24     -70    40
# Comp:  2          [OIII]5007_d      10.59      0.31     -70    40
# Comp:  2            [OI]6300_d     0.4707      0.31     -70    40
# Comp:  2           [NII]6583_d      7.442      0.31     -70    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -71        37
#  comp.  2:       -73        36
# chi2/DOF: 0.8686; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.800      0.24     -71    37
# Comp:  1                Halpha      23.42      0.24     -71    37
# Comp:  2             [SII]6716      4.909      0.24     -73    36
# Comp:  2             [SII]6731      3.876      0.24     -73    36
# Comp:  2              HeII4687     0.3109      0.24     -73    36
# Comp:  2               HeI5876      1.086      0.24     -73    36
# Comp:  2          [OIII]5007_d      10.56      0.30     -73    36
# Comp:  2            [OI]6300_d     0.5876      0.30     -73    36
# Comp:  2           [NII]6583_d      7.090      0.30     -73    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        45
#  comp.  1:       -72        33
#  comp.  2:       -72        30
# chi2/DOF: 0.8628; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.434      0.24     -72    33
# Comp:  1                Halpha      23.21      0.24     -72    33
# Comp:  2             [SII]6716      4.939      0.24     -72    30
# Comp:  2             [SII]6731      3.607      0.24     -72    30
# Comp:  2              HeII4687     0.6795      0.24     -72    30
# Comp:  2               HeI5876     0.9494      0.24     -72    30
# Comp:  2          [OIII]5007_d      9.984      0.30     -72    30
# Comp:  2            [OI]6300_d     0.4497      0.30     -72    30
# Comp:  2           [NII]6583_d      7.106      0.30     -72    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        20
#  comp.  1:       -72        37
#  comp.  2:       -77        40
# chi2/DOF: 0.8640; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.436      0.24     -72    37
# Comp:  1                Halpha      23.64      0.24     -72    37
# Comp:  2             [SII]6716      4.651      0.24     -77    40
# Comp:  2             [SII]6731      3.860      0.24     -77    40
# Comp:  2              HeII4687     0.4265      0.24     -77    40
# Comp:  2               HeI5876      1.095      0.24     -77    40
# Comp:  2          [OIII]5007_d      10.28      0.31     -77    40
# Comp:  2            [OI]6300_d     0.5911      0.31     -77    40
# Comp:  2           [NII]6583_d      7.092      0.31     -77    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -72        35
#  comp.  2:       -78        43
# chi2/DOF: 0.8612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.534      0.24     -72    35
# Comp:  1                Halpha      23.35      0.24     -72    35
# Comp:  2             [SII]6716      5.075      0.24     -78    43
# Comp:  2             [SII]6731      4.141      0.24     -78    43
# Comp:  2              HeII4687     0.5651      0.24     -78    43
# Comp:  2               HeI5876      1.143      0.24     -78    43
# Comp:  2          [OIII]5007_d      10.80      0.31     -78    43
# Comp:  2            [OI]6300_d     0.5175      0.31     -78    43
# Comp:  2           [NII]6583_d      7.212      0.31     -78    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        49
#  comp.  1:       -71        35
#  comp.  2:       -73        44
# chi2/DOF: 0.8612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.531      0.24     -71    35
# Comp:  1                Halpha      23.30      0.24     -71    35
# Comp:  2             [SII]6716      5.058      0.25     -73    44
# Comp:  2             [SII]6731      3.909      0.25     -73    44
# Comp:  2              HeII4687     0.5092      0.25     -73    44
# Comp:  2               HeI5876      1.087      0.25     -73    44
# Comp:  2          [OIII]5007_d      10.63      0.31     -73    44
# Comp:  2            [OI]6300_d     0.5397      0.31     -73    44
# Comp:  2           [NII]6583_d      7.258      0.31     -73    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:       -71        31
#  comp.  2:       -75        42
# chi2/DOF: 0.8551; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.267      0.24     -71    31
# Comp:  1                Halpha      22.88      0.24     -71    31
# Comp:  2             [SII]6716      5.288      0.24     -75    42
# Comp:  2             [SII]6731      3.345      0.24     -75    42
# Comp:  2              HeII4687     0.4317      0.24     -75    42
# Comp:  2               HeI5876      1.117      0.24     -75    42
# Comp:  2          [OIII]5007_d      10.75      0.31     -75    42
# Comp:  2            [OI]6300_d     0.5900      0.31     -75    42
# Comp:  2           [NII]6583_d      7.204      0.31     -75    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -71        33
#  comp.  2:       -71        50
# chi2/DOF: 0.8610; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.860      0.24     -71    33
# Comp:  1                Halpha      22.88      0.24     -71    33
# Comp:  2             [SII]6716      4.834      0.25     -71    50
# Comp:  2             [SII]6731      3.652      0.25     -71    50
# Comp:  2              HeII4687     0.6944      0.25     -71    50
# Comp:  2               HeI5876      1.130      0.25     -71    50
# Comp:  2          [OIII]5007_d      11.44      0.32     -71    50
# Comp:  2            [OI]6300_d     0.4493      0.32     -71    50
# Comp:  2           [NII]6583_d      7.596      0.32     -71    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        24
#  comp.  1:       -72        32
#  comp.  2:       -73        32
# chi2/DOF: 0.8626; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.662      0.24     -72    32
# Comp:  1                Halpha      23.09      0.24     -72    32
# Comp:  2             [SII]6716      4.886      0.24     -73    32
# Comp:  2             [SII]6731      3.799      0.24     -73    32
# Comp:  2              HeII4687     0.6004      0.24     -73    32
# Comp:  2               HeI5876      1.069      0.24     -73    32
# Comp:  2          [OIII]5007_d      9.860      0.30     -73    32
# Comp:  2            [OI]6300_d     0.5644      0.30     -73    32
# Comp:  2           [NII]6583_d      7.077      0.30     -73    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        21
#  comp.  1:       -72        37
#  comp.  2:       -71        47
# chi2/DOF: 0.8560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.069      0.24     -72    37
# Comp:  1                Halpha      23.47      0.24     -72    37
# Comp:  2             [SII]6716      5.208      0.25     -71    47
# Comp:  2             [SII]6731      3.466      0.25     -71    47
# Comp:  2              HeII4687     0.2365      0.25     -71    47
# Comp:  2               HeI5876      1.148      0.25     -71    47
# Comp:  2          [OIII]5007_d      11.23      0.31     -71    47
# Comp:  2            [OI]6300_d     0.4389      0.31     -71    47
# Comp:  2           [NII]6583_d      7.369      0.31     -71    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        39
#  comp.  1:       -72        35
#  comp.  2:       -68        36
# chi2/DOF: 0.8595; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.768      0.24     -72    35
# Comp:  1                Halpha      23.73      0.24     -72    35
# Comp:  2             [SII]6716      5.098      0.24     -68    36
# Comp:  2             [SII]6731      3.730      0.24     -68    36
# Comp:  2              HeII4687     0.4085      0.24     -68    36
# Comp:  2               HeI5876      1.103      0.24     -68    36
# Comp:  2          [OIII]5007_d      10.37      0.30     -68    36
# Comp:  2            [OI]6300_d     0.5249      0.30     -68    36
# Comp:  2           [NII]6583_d      7.018      0.30     -68    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        37
#  comp.  1:       -72        36
#  comp.  2:       -75        48
# chi2/DOF: 0.8603; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.433      0.24     -72    36
# Comp:  1                Halpha      23.48      0.24     -72    36
# Comp:  2             [SII]6716      4.770      0.25     -75    48
# Comp:  2             [SII]6731      4.381      0.25     -75    48
# Comp:  2              HeII4687     0.3178      0.25     -75    48
# Comp:  2               HeI5876      1.212      0.25     -75    48
# Comp:  2          [OIII]5007_d      11.01      0.31     -75    48
# Comp:  2            [OI]6300_d     0.4391      0.31     -75    48
# Comp:  2           [NII]6583_d      7.655      0.31     -75    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -72        30
#  comp.  2:       -73        45
# chi2/DOF: 0.8636; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.769      0.24     -72    30
# Comp:  1                Halpha      22.96      0.24     -72    30
# Comp:  2             [SII]6716      4.981      0.25     -73    45
# Comp:  2             [SII]6731      4.174      0.25     -73    45
# Comp:  2              HeII4687     0.7185      0.25     -73    45
# Comp:  2               HeI5876      1.108      0.25     -73    45
# Comp:  2          [OIII]5007_d      11.09      0.31     -73    45
# Comp:  2            [OI]6300_d     0.6060      0.31     -73    45
# Comp:  2           [NII]6583_d      7.394      0.31     -73    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        26
#  comp.  1:       -72        33
#  comp.  2:       -74        38
# chi2/DOF: 0.8649; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.116      0.24     -72    33
# Comp:  1                Halpha      22.95      0.24     -72    33
# Comp:  2             [SII]6716      5.114      0.24     -74    38
# Comp:  2             [SII]6731      3.859      0.24     -74    38
# Comp:  2              HeII4687     0.4550      0.24     -74    38
# Comp:  2               HeI5876      1.057      0.24     -74    38
# Comp:  2          [OIII]5007_d      10.81      0.30     -74    38
# Comp:  2            [OI]6300_d     0.4046      0.30     -74    38
# Comp:  2           [NII]6583_d      7.196      0.30     -74    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        49
#  comp.  1:       -72        36
#  comp.  2:       -72        48
# chi2/DOF: 0.8663; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.337      0.24     -72    36
# Comp:  1                Halpha      23.73      0.24     -72    36
# Comp:  2             [SII]6716      5.317      0.25     -72    48
# Comp:  2             [SII]6731      4.043      0.25     -72    48
# Comp:  2              HeII4687     0.2867      0.25     -72    48
# Comp:  2               HeI5876      1.075      0.25     -72    48
# Comp:  2          [OIII]5007_d      11.17      0.31     -72    48
# Comp:  2            [OI]6300_d     0.5738      0.31     -72    48
# Comp:  2           [NII]6583_d      7.500      0.31     -72    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        21
#  comp.  1:       -73        34
#  comp.  2:       -75        38
# chi2/DOF: 0.8670; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.081      0.24     -73    34
# Comp:  1                Halpha      23.30      0.24     -73    34
# Comp:  2             [SII]6716      4.940      0.24     -75    38
# Comp:  2             [SII]6731      4.018      0.24     -75    38
# Comp:  2              HeII4687     0.7139      0.24     -75    38
# Comp:  2               HeI5876      1.031      0.24     -75    38
# Comp:  2          [OIII]5007_d      10.84      0.30     -75    38
# Comp:  2            [OI]6300_d     0.4799      0.30     -75    38
# Comp:  2           [NII]6583_d      7.105      0.30     -75    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -71        35
#  comp.  2:       -72        51
# chi2/DOF: 0.8621; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.729      0.24     -71    35
# Comp:  1                Halpha      22.97      0.24     -71    35
# Comp:  2             [SII]6716      5.502      0.25     -72    51
# Comp:  2             [SII]6731      3.793      0.25     -72    51
# Comp:  2              HeII4687     0.8048      0.25     -72    51
# Comp:  2               HeI5876      1.171      0.25     -72    51
# Comp:  2          [OIII]5007_d      11.56      0.32     -72    51
# Comp:  2            [OI]6300_d     0.6634      0.32     -72    51
# Comp:  2           [NII]6583_d      7.704      0.32     -72    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -71        32
#  comp.  2:       -72        45
# chi2/DOF: 0.8634; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.290      0.24     -71    32
# Comp:  1                Halpha      23.06      0.24     -71    32
# Comp:  2             [SII]6716      4.745      0.25     -72    45
# Comp:  2             [SII]6731      4.062      0.25     -72    45
# Comp:  2              HeII4687     0.5433      0.25     -72    45
# Comp:  2               HeI5876      1.073      0.25     -72    45
# Comp:  2          [OIII]5007_d      11.41      0.31     -72    45
# Comp:  2            [OI]6300_d     0.5600      0.31     -72    45
# Comp:  2           [NII]6583_d      7.275      0.31     -72    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -73        33
#  comp.  2:       -74        43
# chi2/DOF: 0.8673; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.283      0.24     -73    33
# Comp:  1                Halpha      23.41      0.24     -73    33
# Comp:  2             [SII]6716      5.066      0.24     -74    43
# Comp:  2             [SII]6731      3.404      0.24     -74    43
# Comp:  2              HeII4687     0.4624      0.24     -74    43
# Comp:  2               HeI5876      1.169      0.24     -74    43
# Comp:  2          [OIII]5007_d      10.98      0.31     -74    43
# Comp:  2            [OI]6300_d     0.5878      0.31     -74    43
# Comp:  2           [NII]6583_d      7.361      0.31     -74    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        53
#  comp.  1:       -73        33
#  comp.  2:       -74        42
# chi2/DOF: 0.8589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.154      0.24     -73    33
# Comp:  1                Halpha      23.22      0.24     -73    33
# Comp:  2             [SII]6716      4.944      0.24     -74    42
# Comp:  2             [SII]6731      4.143      0.24     -74    42
# Comp:  2              HeII4687     0.2544      0.24     -74    42
# Comp:  2               HeI5876      1.076      0.24     -74    42
# Comp:  2          [OIII]5007_d      10.41      0.31     -74    42
# Comp:  2            [OI]6300_d     0.5464      0.31     -74    42
# Comp:  2           [NII]6583_d      7.291      0.31     -74    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -72        35
#  comp.  2:       -70        42
# chi2/DOF: 0.8590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.069      0.24     -72    35
# Comp:  1                Halpha      23.25      0.24     -72    35
# Comp:  2             [SII]6716      4.676      0.24     -70    42
# Comp:  2             [SII]6731      3.963      0.24     -70    42
# Comp:  2              HeII4687     0.3321      0.24     -70    42
# Comp:  2               HeI5876      1.116      0.24     -70    42
# Comp:  2          [OIII]5007_d      10.58      0.31     -70    42
# Comp:  2            [OI]6300_d     0.6113      0.31     -70    42
# Comp:  2           [NII]6583_d      7.228      0.31     -70    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         7
#  comp.  1:       -71        30
#  comp.  2:       -75        36
# chi2/DOF: 0.8617; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.016      0.24     -71    30
# Comp:  1                Halpha      23.17      0.24     -71    30
# Comp:  2             [SII]6716      4.845      0.24     -75    36
# Comp:  2             [SII]6731      3.994      0.24     -75    36
# Comp:  2              HeII4687     0.5467      0.24     -75    36
# Comp:  2               HeI5876      1.107      0.24     -75    36
# Comp:  2          [OIII]5007_d      10.66      0.30     -75    36
# Comp:  2            [OI]6300_d     0.5634      0.30     -75    36
# Comp:  2           [NII]6583_d      7.189      0.30     -75    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -71        35
#  comp.  2:       -74        50
# chi2/DOF: 0.8668; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.042      0.24     -71    35
# Comp:  1                Halpha      23.16      0.24     -71    35
# Comp:  2             [SII]6716      5.182      0.25     -74    50
# Comp:  2             [SII]6731      4.281      0.25     -74    50
# Comp:  2              HeII4687     0.2411      0.25     -74    50
# Comp:  2               HeI5876      1.016      0.25     -74    50
# Comp:  2          [OIII]5007_d      10.92      0.32     -74    50
# Comp:  2            [OI]6300_d     0.4475      0.32     -74    50
# Comp:  2           [NII]6583_d      7.511      0.32     -74    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -72        33
#  comp.  2:       -69        39
# chi2/DOF: 0.8592; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.339      0.24     -72    33
# Comp:  1                Halpha      23.13      0.24     -72    33
# Comp:  2             [SII]6716      4.604      0.24     -69    39
# Comp:  2             [SII]6731      4.095      0.24     -69    39
# Comp:  2              HeII4687     0.3157      0.24     -69    39
# Comp:  2               HeI5876      1.083      0.24     -69    39
# Comp:  2          [OIII]5007_d      10.79      0.31     -69    39
# Comp:  2            [OI]6300_d     0.5864      0.31     -69    39
# Comp:  2           [NII]6583_d      7.035      0.31     -69    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        41
#  comp.  1:       -71        31
#  comp.  2:       -69        44
# chi2/DOF: 0.8571; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.675      0.24     -71    31
# Comp:  1                Halpha      23.20      0.24     -71    31
# Comp:  2             [SII]6716      4.800      0.25     -69    44
# Comp:  2             [SII]6731      3.332      0.25     -69    44
# Comp:  2              HeII4687     0.4442      0.25     -69    44
# Comp:  2               HeI5876      1.031      0.25     -69    44
# Comp:  2          [OIII]5007_d      11.17      0.31     -69    44
# Comp:  2            [OI]6300_d     0.6293      0.31     -69    44
# Comp:  2           [NII]6583_d      7.452      0.31     -69    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -70        34
#  comp.  2:       -71        43
# chi2/DOF: 0.8655; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.937      0.24     -70    34
# Comp:  1                Halpha      23.16      0.24     -70    34
# Comp:  2             [SII]6716      5.334      0.24     -71    43
# Comp:  2             [SII]6731      3.853      0.24     -71    43
# Comp:  2              HeII4687     0.4407      0.24     -71    43
# Comp:  2               HeI5876      1.066      0.24     -71    43
# Comp:  2          [OIII]5007_d      10.87      0.31     -71    43
# Comp:  2            [OI]6300_d     0.6531      0.31     -71    43
# Comp:  2           [NII]6583_d      7.183      0.31     -71    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        76
#  comp.  1:       -73        34
#  comp.  2:       -73        42
# chi2/DOF: 0.8606; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.965      0.24     -73    34
# Comp:  1                Halpha      23.30      0.24     -73    34
# Comp:  2             [SII]6716      4.931      0.24     -73    42
# Comp:  2             [SII]6731      3.562      0.24     -73    42
# Comp:  2              HeII4687     0.8141      0.24     -73    42
# Comp:  2               HeI5876      1.049      0.24     -73    42
# Comp:  2          [OIII]5007_d      10.63      0.31     -73    42
# Comp:  2            [OI]6300_d     0.6089      0.31     -73    42
# Comp:  2           [NII]6583_d      7.078      0.31     -73    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -71        36
#  comp.  2:       -72        40
# chi2/DOF: 0.8631; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.692      0.24     -71    36
# Comp:  1                Halpha      23.22      0.24     -71    36
# Comp:  2             [SII]6716      5.248      0.24     -72    40
# Comp:  2             [SII]6731      4.281      0.24     -72    40
# Comp:  2              HeII4687     0.4793      0.24     -72    40
# Comp:  2               HeI5876      1.087      0.24     -72    40
# Comp:  2          [OIII]5007_d      10.82      0.31     -72    40
# Comp:  2            [OI]6300_d     0.6432      0.31     -72    40
# Comp:  2           [NII]6583_d      7.415      0.31     -72    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         8
#  comp.  1:       -72        34
#  comp.  2:       -70        42
# chi2/DOF: 0.8657; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.055      0.24     -72    34
# Comp:  1                Halpha      23.54      0.24     -72    34
# Comp:  2             [SII]6716      4.815      0.24     -70    42
# Comp:  2             [SII]6731      3.439      0.24     -70    42
# Comp:  2              HeII4687     0.4465      0.24     -70    42
# Comp:  2               HeI5876      1.096      0.24     -70    42
# Comp:  2          [OIII]5007_d      10.82      0.31     -70    42
# Comp:  2            [OI]6300_d     0.6280      0.31     -70    42
# Comp:  2           [NII]6583_d      7.305      0.31     -70    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -71        34
#  comp.  2:       -70        47
# chi2/DOF: 0.8646; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.520      0.24     -71    34
# Comp:  1                Halpha      23.26      0.24     -71    34
# Comp:  2             [SII]6716      5.074      0.25     -70    47
# Comp:  2             [SII]6731      3.780      0.25     -70    47
# Comp:  2              HeII4687     0.7723      0.25     -70    47
# Comp:  2               HeI5876      1.061      0.25     -70    47
# Comp:  2          [OIII]5007_d      11.42      0.31     -70    47
# Comp:  2            [OI]6300_d     0.5602      0.31     -70    47
# Comp:  2           [NII]6583_d      7.490      0.31     -70    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -71        33
#  comp.  2:       -68        41
# chi2/DOF: 0.8656; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.721      0.24     -71    33
# Comp:  1                Halpha      23.13      0.24     -71    33
# Comp:  2             [SII]6716      5.150      0.24     -68    41
# Comp:  2             [SII]6731      3.564      0.24     -68    41
# Comp:  2              HeII4687     0.2940      0.24     -68    41
# Comp:  2               HeI5876      1.027      0.24     -68    41
# Comp:  2          [OIII]5007_d      10.66      0.31     -68    41
# Comp:  2            [OI]6300_d     0.5788      0.31     -68    41
# Comp:  2           [NII]6583_d      7.340      0.31     -68    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -71        35
#  comp.  2:       -72        45
# chi2/DOF: 0.8618; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.225      0.24     -71    35
# Comp:  1                Halpha      23.27      0.24     -71    35
# Comp:  2             [SII]6716      5.001      0.25     -72    45
# Comp:  2             [SII]6731      3.638      0.25     -72    45
# Comp:  2              HeII4687     0.4897      0.25     -72    45
# Comp:  2               HeI5876      1.033      0.25     -72    45
# Comp:  2          [OIII]5007_d      11.12      0.31     -72    45
# Comp:  2            [OI]6300_d     0.5708      0.31     -72    45
# Comp:  2           [NII]6583_d      7.513      0.31     -72    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        17
#  comp.  1:       -72        37
#  comp.  2:       -69        41
# chi2/DOF: 0.8615; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.021      0.24     -72    37
# Comp:  1                Halpha      23.38      0.24     -72    37
# Comp:  2             [SII]6716      4.948      0.24     -69    41
# Comp:  2             [SII]6731      3.685      0.24     -69    41
# Comp:  2              HeII4687     0.4575      0.24     -69    41
# Comp:  2               HeI5876      1.073      0.24     -69    41
# Comp:  2          [OIII]5007_d      10.38      0.31     -69    41
# Comp:  2            [OI]6300_d     0.4647      0.31     -69    41
# Comp:  2           [NII]6583_d      7.110      0.31     -69    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        40
#  comp.  1:       -74        35
#  comp.  2:       -69        46
# chi2/DOF: 0.8602; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.870      0.24     -74    35
# Comp:  1                Halpha      23.57      0.24     -74    35
# Comp:  2             [SII]6716      4.675      0.25     -69    46
# Comp:  2             [SII]6731      3.982      0.25     -69    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.335      0.24     -70    34
# Comp:  1                Halpha      23.06      0.24     -70    34
# Comp:  2             [SII]6716      4.916      0.24     -70    34
# Comp:  2             [SII]6731      3.780      0.24     -70    34
# Comp:  2              HeII4687     0.4876      0.24     -70    34
# Comp:  2               HeI5876      1.121      0.24     -70    34
# Comp:  2          [OIII]5007_d      10.52      0.30     -70    34
# Comp:  2            [OI]6300_d     0.5008      0.30     -70    34
# Comp:  2           [NII]6583_d      6.979      0.30     -70    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        20
#  comp.  1:       -72        37
#  comp.  2:       -69        43
# chi2/DOF: 0.8648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.928      0.24     -72    37
# Comp:  1                Halpha      23.44      0.24     -72    37
# Comp:  2             [SII]6716      4.909      0.25     -69    43
# Comp:  2             [SII]6731      3.784      0.25     -69    43
# Comp:  2              HeII4687     0.8959      0.25     -69    43
# Comp:  2               HeI5876      1.096      0.25     -69    43
# Comp:  2          [OIII]5007_d      10.99      0.31     -69    43
# Comp:  2            [OI]6300_d     0.5824      0.31     -69    43
# Comp:  2           [NII]6583_d      7.417      0.31     -69    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -72        36
#  comp.  2:       -72        44
# chi2/DOF: 0.8689; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.881      0.24     -72    36
# Comp:  1                Halpha      23.43      0.24     -72    36
# Comp:  2             [SII]6716      4.873      0.25     -72    44
# Comp:  2             [SII]6731      3.900      0.25     -72    44
# Comp:  2              HeII4687     0.5421      0.25     -72    44
# Comp:  2               HeI5876      1.016      0.25     -72    44
# Comp:  2          [OIII]5007_d      10.90      0.31     -72    44
# Comp:  2            [OI]6300_d     0.6577      0.31     -72    44
# Comp:  2           [NII]6583_d      7.407      0.31     -72    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        51
#  comp.  1:       -72        34
#  comp.  2:       -76        33
# chi2/DOF: 0.8676; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.106      0.24     -72    34
# Comp:  1                Halpha      23.43      0.24     -72    34
# Comp:  2             [SII]6716      4.779      0.24     -76    33
# Comp:  2             [SII]6731      4.048      0.24     -76    33
# Comp:  2              HeII4687     0.4475      0.24     -76    33
# Comp:  2               HeI5876      1.060      0.24     -76    33
# Comp:  2          [OIII]5007_d      10.07      0.30     -76    33
# Comp:  2            [OI]6300_d     0.4702      0.30     -76    33
# Comp:  2           [NII]6583_d      7.024      0.30     -76    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        48
#  comp.  1:       -72        33
#  comp.  2:       -74        39
# chi2/DOF: 0.8574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.539      0.24     -72    33
# Comp:  1                Halpha      23.41      0.24     -72    33
# Comp:  2             [SII]6716      5.099      0.24     -74    39
# Comp:  2             [SII]6731      4.224      0.24     -74    39
# Comp:  2              HeII4687     0.3654      0.24     -74    39
# Comp:  2               HeI5876      1.049      0.24     -74    39
# Comp:  2          [OIII]5007_d      10.28      0.31     -74    39
# Comp:  2            [OI]6300_d     0.5308      0.31     -74    39
# Comp:  2           [NII]6583_d      7.052      0.31     -74    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -72        32
#  comp.  2:       -73        34
# chi2/DOF: 0.8586; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.869      0.24     -72    32
# Comp:  1                Halpha      23.32      0.24     -72    32
# Comp:  2             [SII]6716      4.917      0.24     -73    34
# Comp:  2             [SII]6731      3.936      0.24     -73    34
# Comp:  2              HeII4687     0.3313      0.24     -73    34
# Comp:  2               HeI5876      1.031      0.24     -73    34
# Comp:  2          [OIII]5007_d      10.00      0.30     -73    34
# Comp:  2            [OI]6300_d     0.6221      0.30     -73    34
# Comp:  2           [NII]6583_d      7.208      0.30     -73    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -72        34
#  comp.  2:       -69        45
# chi2/DOF: 0.8688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.013      0.24     -72    34
# Comp:  1                Halpha      23.14      0.24     -72    34
# Comp:  2             [SII]6716      4.746      0.25     -69    45
# Comp:  2             [SII]6731      4.025      0.25     -69    45
# Comp:  2              HeII4687     0.7910      0.25     -69    45
# Comp:  2               HeI5876      1.054      0.25     -69    45
# Comp:  2          [OIII]5007_d      10.93      0.31     -69    45
# Comp:  2            [OI]6300_d     0.6596      0.31     -69    45
# Comp:  2           [NII]6583_d      7.293      0.31     -69    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        45
#  comp.  1:       -73        37
#  comp.  2:       -75        43
# chi2/DOF: 0.8560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.578      0.24     -73    37
# Comp:  1                Halpha      23.85      0.24     -73    37
# Comp:  2             [SII]6716      5.177      0.24     -75    43
# Comp:  2             [SII]6731      3.755      0.24     -75    43
# Comp:  2              HeII4687     0.7050      0.24     -75    43
# Comp:  2               HeI5876      1.149      0.24     -75    43
# Comp:  2          [OIII]5007_d      10.64      0.31     -75    43
# Comp:  2            [OI]6300_d     0.5556      0.31     -75    43
# Comp:  2           [NII]6583_d      7.248      0.31     -75    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        36
#  comp.  1:       -73        36
#  comp.  2:       -72        46
# chi2/DOF: 0.8572; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.813      0.24     -73    36
# Comp:  1                Halpha      23.44      0.24     -73    36
# Comp:  2             [SII]6716      5.010      0.25     -72    46
# Comp:  2             [SII]6731      4.234      0.25     -72    46
# Comp:  2              HeII4687     0.3921      0.25     -72    46
# Comp:  2               HeI5876      1.183      0.25     -72    46
# Comp:  2          [OIII]5007_d      10.71      0.31     -72    46
# Comp:  2            [OI]6300_d     0.4416      0.31     -72    46
# Comp:  2           [NII]6583_d      7.346      0.31     -72    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        26
#  comp.  1:       -73        37
#  comp.  2:       -72        33
# chi2/DOF: 0.8676; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.973      0.24     -73    37
# Comp:  1                Halpha      23.42      0.24     -73    37
# Comp:  2             [SII]6716      4.750      0.24     -72    33
# Comp:  2             [SII]6731      3.826      0.24     -72    33
# Comp:  2              HeII4687     0.5798      0.24     -72    33
# Comp:  2               HeI5876      1.031      0.24     -72    33
# Comp:  2          [OIII]5007_d      10.22      0.30     -72    33
# Comp:  2            [OI]6300_d     0.4538      0.30     -72    33
# Comp:  2           [NII]6583_d      6.849      0.30     -72    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -71        36
#  comp.  2:       -73        37
# chi2/DOF: 0.8623; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.277      0.24     -71    36
# Comp:  1                Halpha      23.44      0.24     -71    36
# Comp:  2             [SII]6716      4.938      0.24     -73    37
# Comp:  2             [SII]6731      3.971      0.24     -73    37
# Comp:  2              HeII4687     0.4795      0.24     -73    37
# Comp:  2               HeI5876      1.083      0.24     -73    37
# Comp:  2          [OIII]5007_d      10.34      0.30     -73    37
# Comp:  2            [OI]6300_d     0.6865      0.30     -73    37
# Comp:  2           [NII]6583_d      7.199      0.30     -73    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -72        31
#  comp.  2:       -71        33
# chi2/DOF: 0.8609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.678      0.24     -72    31
# Comp:  1                Halpha      22.90      0.24     -72    31
# Comp:  2             [SII]6716      4.739      0.24     -71    33
# Comp:  2             [SII]6731      3.521      0.24     -71    33
# Comp:  2              HeII4687     0.4257      0.24     -71    33
# Comp:  2               HeI5876     0.9914      0.24     -71    33
# Comp:  2          [OIII]5007_d      9.957      0.30     -71    33
# Comp:  2            [OI]6300_d     0.4588      0.30     -71    33
# Comp:  2           [NII]6583_d      7.010      0.30     -71    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        27
#  comp.  1:       -71        34
#  comp.  2:       -76        38
# chi2/DOF: 0.8628; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.537      0.24     -71    34
# Comp:  1                Halpha      23.21      0.24     -71    34
# Comp:  2             [SII]6716      4.597      0.24     -76    38
# Comp:  2             [SII]6731      3.587      0.24     -76    38
# Comp:  2              HeII4687     0.6704      0.24     -76    38
# Comp:  2               HeI5876      1.056      0.24     -76    38
# Comp:  2          [OIII]5007_d      10.31      0.30     -76    38
# Comp:  2            [OI]6300_d     0.6098      0.30     -76    38
# Comp:  2           [NII]6583_d      7.032      0.30     -76    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        39
#  comp.  1:       -73        38
#  comp.  2:       -76        42
# chi2/DOF: 0.8655; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.103      0.24     -73    38
# Comp:  1                Halpha      23.50      0.24     -73    38
# Comp:  2             [SII]6716      5.242      0.24     -76    42
# Comp:  2             [SII]6731      4.057      0.24     -76    42
# Comp:  2              HeII4687     0.4775      0.24     -76    42
# Comp:  2               HeI5876      1.102      0.24     -76    42
# Comp:  2          [OIII]5007_d      10.64      0.31     -76    42
# Comp:  2            [OI]6300_d     0.5654      0.31     -76    42
# Comp:  2           [NII]6583_d      7.171      0.31     -76    42
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.53972102, 0.35780919, 0.31739808, 0.39051081, 0.16358376,
#        0.06907792, 0.39630175, 0.11421263, 0.22996818])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 7.04078727, 31.7453377 ,  6.89728703,  5.35992707,  0.51522172,
#         1.3017915 , 11.13933023,  0.71768508,  9.97344776])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_5_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_5", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_5_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_5_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_5_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.309651    0.023737
# 1        Halpha  1.396146    0.015736
# 2     [SII]6716  0.303340    0.013959
# 3     [SII]6731  0.235727    0.017174
# 4      HeII4687  0.022659    0.007194
# 5       HeI5876  0.057252    0.003038
# 6  [OIII]5007_d  0.489903    0.017429
# 7    [OI]6300_d  0.031563    0.005023
# 8   [NII]6583_d  0.438628    0.010114
#           Name      Flux  Error_flux
# 0        Hbeta  0.309651    0.023737
# 1       Halpha  1.396146    0.015736
# 2    [SII]6716  0.303340    0.013959
# 3    [SII]6731  0.235727    0.017174
# 4     HeII4687  0.022659    0.007194
# 5      HeI5876  0.057252    0.003038
# 6   [OIII]4959  0.122476    0.017429
# 7   [OIII]5007  0.367427    0.017429
# 8     [OI]6300  0.023673    0.005023
# 9     [OI]6364  0.007891    0.005023
# 10   [NII]6548  0.109657    0.010114
# 11   [NII]6583  0.328971    0.010114

# %%
np.median(flux_rf_rebin)
# Out:
# 0.043979562596145716
