# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_16.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_16']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.09495076 0.09768874 0.07555393 ... 0.04793757 0.04771496 0.04110616] [0.0061128 0.0061128 0.0061128 ... 0.0061128 0.0061128 0.0061128]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        14
# chi2/DOF: 0.006558; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         9
# chi2/DOF: 0.004835; DOF: 1908; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 13; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-44.08396466,   9.14488257])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -59        31
#  comp.  2:       -57        39
# chi2/DOF: 1.394; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.85      0.19     -59    31
# Comp:  1                Halpha      96.50      0.19     -59    31
# Comp:  2             [SII]6716      17.61      0.20     -57    39
# Comp:  2             [SII]6731      12.86      0.20     -57    39
# Comp:  2              HeII4687      0.000      0.20     -57    39
# Comp:  2               HeI5876      3.153      0.20     -57    39
# Comp:  2          [OIII]5007_d      42.13      0.25     -57    39
# Comp:  2            [OI]6300_d      2.680      0.25     -57    39
# Comp:  2           [NII]6583_d      23.93      0.25     -57    39
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  131.5; gas flux:     30 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  405.8; gas flux:    132 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  70.61; gas flux:     25 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  54.57; gas flux:     18 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  13.41; gas flux:      4 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  136.8; gas flux:     44 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  8.667; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  74.17; gas flux:     33 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        63
#  comp.  1:       -59        35
#  comp.  2:       -61        31
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.44      0.20     -59    35
# Comp:  1                Halpha      98.88      0.20     -59    35
# Comp:  2             [SII]6716      17.31      0.19     -61    31
# Comp:  2             [SII]6731      13.49      0.19     -61    31
# Comp:  2              HeII4687    0.09353      0.19     -61    31
# Comp:  2               HeI5876      3.021      0.19     -61    31
# Comp:  2          [OIII]5007_d      41.38      0.24     -61    31
# Comp:  2            [OI]6300_d      2.146      0.24     -61    31
# Comp:  2           [NII]6583_d      23.24      0.24     -61    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -57        32
#  comp.  2:       -57        34
# chi2/DOF: 1.297; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.53      0.19     -57    32
# Comp:  1                Halpha      96.97      0.19     -57    32
# Comp:  2             [SII]6716      17.43      0.20     -57    34
# Comp:  2             [SII]6731      12.28      0.20     -57    34
# Comp:  2              HeII4687      0.000      0.20     -57    34
# Comp:  2               HeI5876      3.372      0.20     -57    34
# Comp:  2          [OIII]5007_d      40.23      0.25     -57    34
# Comp:  2            [OI]6300_d      2.782      0.25     -57    34
# Comp:  2           [NII]6583_d      24.09      0.25     -57    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        85
#  comp.  1:       -59        29
#  comp.  2:       -52        43
# chi2/DOF: 1.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.80      0.19     -59    29
# Comp:  1                Halpha      96.45      0.19     -59    29
# Comp:  2             [SII]6716      16.97      0.20     -52    43
# Comp:  2             [SII]6731      14.36      0.20     -52    43
# Comp:  2              HeII4687     0.3032      0.20     -52    43
# Comp:  2               HeI5876      2.995      0.20     -52    43
# Comp:  2          [OIII]5007_d      41.61      0.25     -52    43
# Comp:  2            [OI]6300_d      2.558      0.25     -52    43
# Comp:  2           [NII]6583_d      24.40      0.25     -52    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        19
#  comp.  1:       -58        27
#  comp.  2:       -62        32
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.08      0.19     -58    27
# Comp:  1                Halpha      94.77      0.19     -58    27
# Comp:  2             [SII]6716      16.85      0.19     -62    32
# Comp:  2             [SII]6731      12.69      0.19     -62    32
# Comp:  2              HeII4687      0.000      0.19     -62    32
# Comp:  2               HeI5876      3.104      0.19     -62    32
# Comp:  2          [OIII]5007_d      40.95      0.25     -62    32
# Comp:  2            [OI]6300_d      2.213      0.25     -62    32
# Comp:  2           [NII]6583_d      23.13      0.25     -62    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:       -59        28
#  comp.  2:       -60        32
# chi2/DOF: 1.218; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.58      0.19     -59    28
# Comp:  1                Halpha      95.80      0.19     -59    28
# Comp:  2             [SII]6716      18.21      0.19     -60    32
# Comp:  2             [SII]6731      11.59      0.19     -60    32
# Comp:  2              HeII4687      0.000      0.19     -60    32
# Comp:  2               HeI5876      2.891      0.19     -60    32
# Comp:  2          [OIII]5007_d      42.46      0.25     -60    32
# Comp:  2            [OI]6300_d      2.605      0.25     -60    32
# Comp:  2           [NII]6583_d      23.71      0.25     -60    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        67
#  comp.  1:       -59        25
#  comp.  2:       -51        44
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.55      0.19     -59    25
# Comp:  1                Halpha      94.85      0.19     -59    25
# Comp:  2             [SII]6716      17.82      0.20     -51    44
# Comp:  2             [SII]6731      13.24      0.20     -51    44
# Comp:  2              HeII4687      0.000      0.20     -51    44
# Comp:  2               HeI5876      3.505      0.20     -51    44
# Comp:  2          [OIII]5007_d      41.88      0.26     -51    44
# Comp:  2            [OI]6300_d      2.475      0.26     -51    44
# Comp:  2           [NII]6583_d      23.98      0.26     -51    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -57        31
#  comp.  2:       -62        38
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.47      0.19     -57    31
# Comp:  1                Halpha      96.47      0.19     -57    31
# Comp:  2             [SII]6716      16.48      0.20     -62    38
# Comp:  2             [SII]6731      13.77      0.20     -62    38
# Comp:  2              HeII4687      0.000      0.20     -62    38
# Comp:  2               HeI5876      3.144      0.20     -62    38
# Comp:  2          [OIII]5007_d      42.72      0.25     -62    38
# Comp:  2            [OI]6300_d      2.750      0.25     -62    38
# Comp:  2           [NII]6583_d      24.29      0.25     -62    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        60
#  comp.  1:       -59        28
#  comp.  2:       -53        49
# chi2/DOF: 1.161; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 99; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.35      0.19     -59    28
# Comp:  1                Halpha      96.00      0.19     -59    28
# Comp:  2             [SII]6716      18.19      0.21     -53    49
# Comp:  2             [SII]6731      13.58      0.21     -53    49
# Comp:  2              HeII4687     0.3051      0.21     -53    49
# Comp:  2               HeI5876      3.454      0.21     -53    49
# Comp:  2          [OIII]5007_d      43.02      0.26     -53    49
# Comp:  2            [OI]6300_d      3.269      0.26     -53    49
# Comp:  2           [NII]6583_d      24.40      0.26     -53    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        34
#  comp.  1:       -58        26
#  comp.  2:       -55        42
# chi2/DOF: 1.200; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 36; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.56      0.19     -58    26
# Comp:  1                Halpha      95.11      0.19     -58    26
# Comp:  2             [SII]6716      18.70      0.20     -55    42
# Comp:  2             [SII]6731      12.74      0.20     -55    42
# Comp:  2              HeII4687     0.3253      0.20     -55    42
# Comp:  2               HeI5876      3.349      0.20     -55    42
# Comp:  2          [OIII]5007_d      44.15      0.25     -55    42
# Comp:  2            [OI]6300_d      2.547      0.25     -55    42
# Comp:  2           [NII]6583_d      24.69      0.25     -55    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90         1
#  comp.  1:       -57        35
#  comp.  2:       -59        33
# chi2/DOF: 1.281; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.64      0.20     -57    35
# Comp:  1                Halpha      98.26      0.20     -57    35
# Comp:  2             [SII]6716      17.42      0.20     -59    33
# Comp:  2             [SII]6731      12.85      0.20     -59    33
# Comp:  2              HeII4687      0.000      0.20     -59    33
# Comp:  2               HeI5876      3.336      0.20     -59    33
# Comp:  2          [OIII]5007_d      40.15      0.25     -59    33
# Comp:  2            [OI]6300_d      2.851      0.25     -59    33
# Comp:  2           [NII]6583_d      24.20      0.25     -59    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        32
#  comp.  1:       -60        27
#  comp.  2:       -56        29
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.33      0.19     -60    27
# Comp:  1                Halpha      95.92      0.19     -60    27
# Comp:  2             [SII]6716      16.82      0.19     -56    29
# Comp:  2             [SII]6731      12.40      0.19     -56    29
# Comp:  2              HeII4687     0.2980      0.19     -56    29
# Comp:  2               HeI5876      3.263      0.19     -56    29
# Comp:  2          [OIII]5007_d      39.16      0.24     -56    29
# Comp:  2            [OI]6300_d      2.744      0.24     -56    29
# Comp:  2           [NII]6583_d      22.87      0.24     -56    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -59        37
#  comp.  2:       -58        35
# chi2/DOF: 1.199; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.20      0.20     -59    37
# Comp:  1                Halpha      99.04      0.20     -59    37
# Comp:  2             [SII]6716      17.34      0.20     -58    35
# Comp:  2             [SII]6731      12.80      0.20     -58    35
# Comp:  2              HeII4687      0.000      0.20     -58    35
# Comp:  2               HeI5876      3.638      0.20     -58    35
# Comp:  2          [OIII]5007_d      39.52      0.25     -58    35
# Comp:  2            [OI]6300_d      2.556      0.25     -58    35
# Comp:  2           [NII]6583_d      23.77      0.25     -58    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -60        30
#  comp.  2:       -62        36
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.44      0.19     -60    30
# Comp:  1                Halpha      96.68      0.19     -60    30
# Comp:  2             [SII]6716      18.55      0.20     -62    36
# Comp:  2             [SII]6731      13.75      0.20     -62    36
# Comp:  2              HeII4687     0.1441      0.20     -62    36
# Comp:  2               HeI5876      3.209      0.20     -62    36
# Comp:  2          [OIII]5007_d      42.31      0.25     -62    36
# Comp:  2            [OI]6300_d      2.578      0.25     -62    36
# Comp:  2           [NII]6583_d      23.63      0.25     -62    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        40
#  comp.  1:       -58        33
#  comp.  2:       -56        44
# chi2/DOF: 1.226; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.99      0.20     -58    33
# Comp:  1                Halpha      97.47      0.20     -58    33
# Comp:  2             [SII]6716      19.10      0.20     -56    44
# Comp:  2             [SII]6731      12.98      0.20     -56    44
# Comp:  2              HeII4687      0.000      0.20     -56    44
# Comp:  2               HeI5876      3.546      0.20     -56    44
# Comp:  2          [OIII]5007_d      44.76      0.26     -56    44
# Comp:  2            [OI]6300_d      2.730      0.26     -56    44
# Comp:  2           [NII]6583_d      24.40      0.26     -56    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -58        24
#  comp.  2:       -58        33
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.72      0.19     -58    24
# Comp:  1                Halpha      94.39      0.19     -58    24
# Comp:  2             [SII]6716      17.45      0.20     -58    33
# Comp:  2             [SII]6731      11.35      0.20     -58    33
# Comp:  2              HeII4687      0.000      0.20     -58    33
# Comp:  2               HeI5876      3.205      0.20     -58    33
# Comp:  2          [OIII]5007_d      40.67      0.25     -58    33
# Comp:  2            [OI]6300_d      2.534      0.25     -58    33
# Comp:  2           [NII]6583_d      22.95      0.25     -58    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -58        29
#  comp.  2:       -55        42
# chi2/DOF: 1.303; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.72      0.19     -58    29
# Comp:  1                Halpha      95.60      0.19     -58    29
# Comp:  2             [SII]6716      18.03      0.20     -55    42
# Comp:  2             [SII]6731      12.15      0.20     -55    42
# Comp:  2              HeII4687     0.3488      0.20     -55    42
# Comp:  2               HeI5876      3.334      0.20     -55    42
# Comp:  2          [OIII]5007_d      43.60      0.25     -55    42
# Comp:  2            [OI]6300_d      2.423      0.25     -55    42
# Comp:  2           [NII]6583_d      24.48      0.25     -55    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -60        28
#  comp.  2:       -58        26
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.48      0.19     -60    28
# Comp:  1                Halpha      95.07      0.19     -60    28
# Comp:  2             [SII]6716      17.92      0.19     -58    26
# Comp:  2             [SII]6731      12.38      0.19     -58    26
# Comp:  2              HeII4687     0.1059      0.19     -58    26
# Comp:  2               HeI5876      3.176      0.19     -58    26
# Comp:  2          [OIII]5007_d      38.89      0.24     -58    26
# Comp:  2            [OI]6300_d      2.338      0.24     -58    26
# Comp:  2           [NII]6583_d      22.92      0.24     -58    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87         1
#  comp.  1:       -58        34
#  comp.  2:       -55        42
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.42      0.20     -58    34
# Comp:  1                Halpha      97.95      0.20     -58    34
# Comp:  2             [SII]6716      17.94      0.20     -55    42
# Comp:  2             [SII]6731      11.67      0.20     -55    42
# Comp:  2              HeII4687      0.000      0.20     -55    42
# Comp:  2               HeI5876      3.469      0.20     -55    42
# Comp:  2          [OIII]5007_d      43.41      0.25     -55    42
# Comp:  2            [OI]6300_d      2.385      0.25     -55    42
# Comp:  2           [NII]6583_d      24.25      0.25     -55    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        40
#  comp.  1:       -59        29
#  comp.  2:       -54        29
# chi2/DOF: 1.208; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.75      0.19     -59    29
# Comp:  1                Halpha      95.91      0.19     -59    29
# Comp:  2             [SII]6716      18.00      0.19     -54    29
# Comp:  2             [SII]6731      12.42      0.19     -54    29
# Comp:  2              HeII4687      0.000      0.19     -54    29
# Comp:  2               HeI5876      2.969      0.19     -54    29
# Comp:  2          [OIII]5007_d      39.83      0.24     -54    29
# Comp:  2            [OI]6300_d      3.119      0.24     -54    29
# Comp:  2           [NII]6583_d      22.81      0.24     -54    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -60        31
#  comp.  2:       -59        45
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.12      0.19     -60    31
# Comp:  1                Halpha      96.78      0.19     -60    31
# Comp:  2             [SII]6716      17.24      0.20     -59    45
# Comp:  2             [SII]6731      14.27      0.20     -59    45
# Comp:  2              HeII4687      0.000      0.20     -59    45
# Comp:  2               HeI5876      2.799      0.20     -59    45
# Comp:  2          [OIII]5007_d      44.30      0.26     -59    45
# Comp:  2            [OI]6300_d      2.736      0.26     -59    45
# Comp:  2           [NII]6583_d      24.94      0.26     -59    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
#  comp.  1:       -59        28
#  comp.  2:       -57        41
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.49      0.19     -59    28
# Comp:  1                Halpha      95.87      0.19     -59    28
# Comp:  2             [SII]6716      17.44      0.20     -57    41
# Comp:  2             [SII]6731      14.25      0.20     -57    41
# Comp:  2              HeII4687     0.3396      0.20     -57    41
# Comp:  2               HeI5876      3.512      0.20     -57    41
# Comp:  2          [OIII]5007_d      42.00      0.25     -57    41
# Comp:  2            [OI]6300_d      3.057      0.25     -57    41
# Comp:  2           [NII]6583_d      24.23      0.25     -57    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -60        29
#  comp.  2:       -63        32
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.62      0.19     -60    29
# Comp:  1                Halpha      95.16      0.19     -60    29
# Comp:  2             [SII]6716      17.35      0.19     -63    32
# Comp:  2             [SII]6731      12.63      0.19     -63    32
# Comp:  2              HeII4687      0.000      0.19     -63    32
# Comp:  2               HeI5876      3.220      0.19     -63    32
# Comp:  2          [OIII]5007_d      41.68      0.25     -63    32
# Comp:  2            [OI]6300_d      2.719      0.25     -63    32
# Comp:  2           [NII]6583_d      23.91      0.25     -63    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134        46
#  comp.  1:       -58        35
#  comp.  2:       -56        44
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.25      0.20     -58    35
# Comp:  1                Halpha      98.60      0.20     -58    35
# Comp:  2             [SII]6716      17.79      0.20     -56    44
# Comp:  2             [SII]6731      13.44      0.20     -56    44
# Comp:  2              HeII4687      0.000      0.20     -56    44
# Comp:  2               HeI5876      2.922      0.20     -56    44
# Comp:  2          [OIII]5007_d      42.81      0.26     -56    44
# Comp:  2            [OI]6300_d      3.016      0.26     -56    44
# Comp:  2           [NII]6583_d      23.68      0.26     -56    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        35
#  comp.  1:       -60        31
#  comp.  2:       -61        36
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.63      0.19     -60    31
# Comp:  1                Halpha      96.90      0.19     -60    31
# Comp:  2             [SII]6716      18.30      0.20     -61    36
# Comp:  2             [SII]6731      12.96      0.20     -61    36
# Comp:  2              HeII4687     0.2926      0.20     -61    36
# Comp:  2               HeI5876      3.213      0.20     -61    36
# Comp:  2          [OIII]5007_d      42.99      0.25     -61    36
# Comp:  2            [OI]6300_d      2.801      0.25     -61    36
# Comp:  2           [NII]6583_d      23.84      0.25     -61    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -57        34
#  comp.  2:       -57        50
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.80      0.20     -57    34
# Comp:  1                Halpha      97.41      0.20     -57    34
# Comp:  2             [SII]6716      19.40      0.21     -57    50
# Comp:  2             [SII]6731      12.51      0.21     -57    50
# Comp:  2              HeII4687    0.03317      0.21     -57    50
# Comp:  2               HeI5876      3.245      0.21     -57    50
# Comp:  2          [OIII]5007_d      45.80      0.26     -57    50
# Comp:  2            [OI]6300_d      2.498      0.26     -57    50
# Comp:  2           [NII]6583_d      24.68      0.26     -57    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        39
#  comp.  1:       -59        25
#  comp.  2:       -58        43
# chi2/DOF: 1.216; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.50      0.19     -59    25
# Comp:  1                Halpha      94.99      0.19     -59    25
# Comp:  2             [SII]6716      17.15      0.20     -58    43
# Comp:  2             [SII]6731      13.23      0.20     -58    43
# Comp:  2              HeII4687     0.4488      0.20     -58    43
# Comp:  2               HeI5876      3.457      0.20     -58    43
# Comp:  2          [OIII]5007_d      45.31      0.25     -58    43
# Comp:  2            [OI]6300_d      2.794      0.25     -58    43
# Comp:  2           [NII]6583_d      24.12      0.25     -58    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:       -61        31
#  comp.  2:       -59        45
# chi2/DOF: 1.173; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.92      0.19     -61    31
# Comp:  1                Halpha      97.33      0.19     -61    31
# Comp:  2             [SII]6716      18.01      0.20     -59    45
# Comp:  2             [SII]6731      12.05      0.20     -59    45
# Comp:  2              HeII4687     0.3823      0.20     -59    45
# Comp:  2               HeI5876      3.387      0.20     -59    45
# Comp:  2          [OIII]5007_d      45.12      0.26     -59    45
# Comp:  2            [OI]6300_d      2.694      0.26     -59    45
# Comp:  2           [NII]6583_d      24.62      0.26     -59    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -60        28
#  comp.  2:       -57        38
# chi2/DOF: 1.308; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.92      0.19     -60    28
# Comp:  1                Halpha      95.84      0.19     -60    28
# Comp:  2             [SII]6716      17.38      0.20     -57    38
# Comp:  2             [SII]6731      13.79      0.20     -57    38
# Comp:  2              HeII4687    0.01471      0.20     -57    38
# Comp:  2               HeI5876      2.974      0.20     -57    38
# Comp:  2          [OIII]5007_d      40.48      0.25     -57    38
# Comp:  2            [OI]6300_d      3.059      0.25     -57    38
# Comp:  2           [NII]6583_d      23.91      0.25     -57    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -59        31
#  comp.  2:       -54        45
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.02      0.19     -59    31
# Comp:  1                Halpha      96.91      0.19     -59    31
# Comp:  2             [SII]6716      17.99      0.20     -54    45
# Comp:  2             [SII]6731      13.39      0.20     -54    45
# Comp:  2              HeII4687      0.000      0.20     -54    45
# Comp:  2               HeI5876      3.356      0.20     -54    45
# Comp:  2          [OIII]5007_d      43.89      0.26     -54    45
# Comp:  2            [OI]6300_d      2.744      0.26     -54    45
# Comp:  2           [NII]6583_d      24.05      0.26     -54    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        50
#  comp.  1:       -59        24
#  comp.  2:       -61        29
# chi2/DOF: 1.135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.64      0.19     -59    24
# Comp:  1                Halpha      94.65      0.19     -59    24
# Comp:  2             [SII]6716      17.32      0.19     -61    29
# Comp:  2             [SII]6731      12.87      0.19     -61    29
# Comp:  2              HeII4687    0.04275      0.19     -61    29
# Comp:  2               HeI5876      3.266      0.19     -61    29
# Comp:  2          [OIII]5007_d      41.47      0.24     -61    29
# Comp:  2            [OI]6300_d      2.795      0.24     -61    29
# Comp:  2           [NII]6583_d      23.54      0.24     -61    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -57        33
#  comp.  2:       -56        43
# chi2/DOF: 1.321; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.86      0.20     -57    33
# Comp:  1                Halpha      97.34      0.20     -57    33
# Comp:  2             [SII]6716      18.24      0.20     -56    43
# Comp:  2             [SII]6731      14.33      0.20     -56    43
# Comp:  2              HeII4687    0.02675      0.20     -56    43
# Comp:  2               HeI5876      2.945      0.20     -56    43
# Comp:  2          [OIII]5007_d      42.77      0.25     -56    43
# Comp:  2            [OI]6300_d      2.523      0.25     -56    43
# Comp:  2           [NII]6583_d      24.24      0.25     -56    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -58        28
#  comp.  2:       -54        44
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.06      0.19     -58    28
# Comp:  1                Halpha      95.58      0.19     -58    28
# Comp:  2             [SII]6716      19.19      0.20     -54    44
# Comp:  2             [SII]6731      14.03      0.20     -54    44
# Comp:  2              HeII4687      0.000      0.20     -54    44
# Comp:  2               HeI5876      3.084      0.20     -54    44
# Comp:  2          [OIII]5007_d      45.24      0.26     -54    44
# Comp:  2            [OI]6300_d      2.664      0.26     -54    44
# Comp:  2           [NII]6583_d      24.19      0.26     -54    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        84
#  comp.  1:       -58        25
#  comp.  2:       -55        44
# chi2/DOF: 1.204; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.88      0.19     -58    25
# Comp:  1                Halpha      94.63      0.19     -58    25
# Comp:  2             [SII]6716      19.28      0.20     -55    44
# Comp:  2             [SII]6731      11.72      0.20     -55    44
# Comp:  2              HeII4687      0.000      0.20     -55    44
# Comp:  2               HeI5876      3.044      0.20     -55    44
# Comp:  2          [OIII]5007_d      45.17      0.26     -55    44
# Comp:  2            [OI]6300_d      2.826      0.26     -55    44
# Comp:  2           [NII]6583_d      24.86      0.26     -55    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -57        27
#  comp.  2:       -53        41
# chi2/DOF: 1.276; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.62      0.19     -57    27
# Comp:  1                Halpha      94.73      0.19     -57    27
# Comp:  2             [SII]6716      18.77      0.20     -53    41
# Comp:  2             [SII]6731      12.87      0.20     -53    41
# Comp:  2              HeII4687      0.000      0.20     -53    41
# Comp:  2               HeI5876      3.333      0.20     -53    41
# Comp:  2          [OIII]5007_d      41.99      0.25     -53    41
# Comp:  2            [OI]6300_d      2.652      0.25     -53    41
# Comp:  2           [NII]6583_d      24.43      0.25     -53    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -60        28
#  comp.  2:       -58        30
# chi2/DOF: 1.297; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.00      0.19     -60    28
# Comp:  1                Halpha      95.52      0.19     -60    28
# Comp:  2             [SII]6716      17.34      0.19     -58    30
# Comp:  2             [SII]6731      11.53      0.19     -58    30
# Comp:  2              HeII4687    0.04479      0.19     -58    30
# Comp:  2               HeI5876      3.373      0.19     -58    30
# Comp:  2          [OIII]5007_d      39.44      0.24     -58    30
# Comp:  2            [OI]6300_d      2.545      0.24     -58    30
# Comp:  2           [NII]6583_d      23.27      0.24     -58    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -58        34
#  comp.  2:       -59        34
# chi2/DOF: 1.277; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.82      0.20     -58    34
# Comp:  1                Halpha      97.20      0.20     -58    34
# Comp:  2             [SII]6716      18.28      0.20     -59    34
# Comp:  2             [SII]6731      13.91      0.20     -59    34
# Comp:  2              HeII4687     0.4254      0.20     -59    34
# Comp:  2               HeI5876      3.315      0.20     -59    34
# Comp:  2          [OIII]5007_d      42.17      0.25     -59    34
# Comp:  2            [OI]6300_d      3.040      0.25     -59    34
# Comp:  2           [NII]6583_d      23.52      0.25     -59    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        61
#  comp.  1:       -59        33
#  comp.  2:       -52        35
# chi2/DOF: 1.184; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.65      0.20     -59    33
# Comp:  1                Halpha      97.94      0.20     -59    33
# Comp:  2             [SII]6716      16.30      0.20     -52    35
# Comp:  2             [SII]6731      11.49      0.20     -52    35
# Comp:  2              HeII4687     0.3764      0.20     -52    35
# Comp:  2               HeI5876      2.707      0.20     -52    35
# Comp:  2          [OIII]5007_d      41.94      0.25     -52    35
# Comp:  2            [OI]6300_d      2.551      0.25     -52    35
# Comp:  2           [NII]6583_d      23.42      0.25     -52    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -58        27
#  comp.  2:       -58        47
# chi2/DOF: 1.220; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.92      0.19     -58    27
# Comp:  1                Halpha      95.46      0.19     -58    27
# Comp:  2             [SII]6716      18.27      0.20     -58    47
# Comp:  2             [SII]6731      12.99      0.20     -58    47
# Comp:  2              HeII4687      0.000      0.20     -58    47
# Comp:  2               HeI5876      2.994      0.20     -58    47
# Comp:  2          [OIII]5007_d      45.52      0.26     -58    47
# Comp:  2            [OI]6300_d      2.785      0.26     -58    47
# Comp:  2           [NII]6583_d      25.28      0.26     -58    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -58        25
#  comp.  2:       -52        35
# chi2/DOF: 1.235; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.60      0.19     -58    25
# Comp:  1                Halpha      94.69      0.19     -58    25
# Comp:  2             [SII]6716      17.31      0.20     -52    35
# Comp:  2             [SII]6731      12.39      0.20     -52    35
# Comp:  2              HeII4687      0.000      0.20     -52    35
# Comp:  2               HeI5876      3.227      0.20     -52    35
# Comp:  2          [OIII]5007_d      41.12      0.25     -52    35
# Comp:  2            [OI]6300_d      2.429      0.25     -52    35
# Comp:  2           [NII]6583_d      23.95      0.25     -52    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -58        33
#  comp.  2:       -57        47
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.12      0.19     -58    33
# Comp:  1                Halpha      96.66      0.19     -58    33
# Comp:  2             [SII]6716      18.41      0.20     -57    47
# Comp:  2             [SII]6731      12.31      0.20     -57    47
# Comp:  2              HeII4687      0.000      0.20     -57    47
# Comp:  2               HeI5876      3.322      0.20     -57    47
# Comp:  2          [OIII]5007_d      45.47      0.26     -57    47
# Comp:  2            [OI]6300_d      2.604      0.26     -57    47
# Comp:  2           [NII]6583_d      25.40      0.26     -57    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -58        36
#  comp.  2:       -51        42
# chi2/DOF: 1.135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.39      0.20     -58    36
# Comp:  1                Halpha      98.68      0.20     -58    36
# Comp:  2             [SII]6716      17.60      0.20     -51    42
# Comp:  2             [SII]6731      12.81      0.20     -51    42
# Comp:  2              HeII4687     0.4352      0.20     -51    42
# Comp:  2               HeI5876      3.362      0.20     -51    42
# Comp:  2          [OIII]5007_d      41.58      0.25     -51    42
# Comp:  2            [OI]6300_d      2.741      0.25     -51    42
# Comp:  2           [NII]6583_d      24.08      0.25     -51    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:       -60        31
#  comp.  2:       -55        47
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.12      0.19     -60    31
# Comp:  1                Halpha      97.54      0.19     -60    31
# Comp:  2             [SII]6716      17.03      0.20     -55    47
# Comp:  2             [SII]6731      13.36      0.20     -55    47
# Comp:  2              HeII4687      0.000      0.20     -55    47
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.92      0.19     -57    30
# Comp:  1                Halpha      96.32      0.19     -57    30
# Comp:  2             [SII]6716      15.78      0.19     -59    28
# Comp:  2             [SII]6731      12.41      0.19     -59    28
# Comp:  2              HeII4687      0.000      0.19     -59    28
# Comp:  2               HeI5876      3.178      0.19     -59    28
# Comp:  2          [OIII]5007_d      41.31      0.24     -59    28
# Comp:  2            [OI]6300_d      2.717      0.24     -59    28
# Comp:  2           [NII]6583_d      23.48      0.24     -59    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -59        36
#  comp.  2:       -50        40
# chi2/DOF: 1.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.13      0.20     -59    36
# Comp:  1                Halpha      98.62      0.20     -59    36
# Comp:  2             [SII]6716      17.56      0.20     -50    40
# Comp:  2             [SII]6731      12.65      0.20     -50    40
# Comp:  2              HeII4687      0.000      0.20     -50    40
# Comp:  2               HeI5876      3.102      0.20     -50    40
# Comp:  2          [OIII]5007_d      42.45      0.25     -50    40
# Comp:  2            [OI]6300_d      2.961      0.25     -50    40
# Comp:  2           [NII]6583_d      24.31      0.25     -50    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -60        30
#  comp.  2:       -55        46
# chi2/DOF: 1.302; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.10      0.19     -60    30
# Comp:  1                Halpha      96.67      0.19     -60    30
# Comp:  2             [SII]6716      16.93      0.20     -55    46
# Comp:  2             [SII]6731      13.50      0.20     -55    46
# Comp:  2              HeII4687      0.000      0.20     -55    46
# Comp:  2               HeI5876      3.666      0.20     -55    46
# Comp:  2          [OIII]5007_d      43.27      0.26     -55    46
# Comp:  2            [OI]6300_d      2.969      0.26     -55    46
# Comp:  2           [NII]6583_d      23.94      0.26     -55    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        88
#  comp.  1:       -59        29
#  comp.  2:       -61        32
# chi2/DOF: 1.296; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.51      0.19     -59    29
# Comp:  1                Halpha      96.29      0.19     -59    29
# Comp:  2             [SII]6716      17.54      0.19     -61    32
# Comp:  2             [SII]6731      13.47      0.19     -61    32
# Comp:  2              HeII4687     0.3667      0.19     -61    32
# Comp:  2               HeI5876      3.087      0.19     -61    32
# Comp:  2          [OIII]5007_d      40.72      0.25     -61    32
# Comp:  2            [OI]6300_d      2.597      0.25     -61    32
# Comp:  2           [NII]6583_d      23.08      0.25     -61    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11        58
#  comp.  1:       -60        27
#  comp.  2:       -57        33
# chi2/DOF: 1.247; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.60      0.19     -60    27
# Comp:  1                Halpha      96.20      0.19     -60    27
# Comp:  2             [SII]6716      16.97      0.20     -57    33
# Comp:  2             [SII]6731      13.66      0.20     -57    33
# Comp:  2              HeII4687      0.000      0.20     -57    33
# Comp:  2               HeI5876      2.871      0.20     -57    33
# Comp:  2          [OIII]5007_d      39.88      0.25     -57    33
# Comp:  2            [OI]6300_d      2.614      0.25     -57    33
# Comp:  2           [NII]6583_d      23.42      0.25     -57    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:       -59        28
#  comp.  2:       -58        28
# chi2/DOF: 1.155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.46      0.19     -59    28
# Comp:  1                Halpha      95.82      0.19     -59    28
# Comp:  2             [SII]6716      15.69      0.19     -58    28
# Comp:  2             [SII]6731      13.28      0.19     -58    28
# Comp:  2              HeII4687      0.000      0.19     -58    28
# Comp:  2               HeI5876      3.121      0.19     -58    28
# Comp:  2          [OIII]5007_d      38.52      0.24     -58    28
# Comp:  2            [OI]6300_d      2.081      0.24     -58    28
# Comp:  2           [NII]6583_d      23.39      0.24     -58    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -59        27
#  comp.  2:       -54        39
# chi2/DOF: 1.326; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.88      0.19     -59    27
# Comp:  1                Halpha      94.89      0.19     -59    27
# Comp:  2             [SII]6716      16.79      0.20     -54    39
# Comp:  2             [SII]6731      13.05      0.20     -54    39
# Comp:  2              HeII4687   0.005083      0.20     -54    39
# Comp:  2               HeI5876      3.035      0.20     -54    39
# Comp:  2          [OIII]5007_d      41.39      0.25     -54    39
# Comp:  2            [OI]6300_d      2.564      0.25     -54    39
# Comp:  2           [NII]6583_d      23.42      0.25     -54    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        39
#  comp.  1:       -59        34
#  comp.  2:       -62        36
# chi2/DOF: 1.273; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.45      0.20     -59    34
# Comp:  1                Halpha      98.53      0.20     -59    34
# Comp:  2             [SII]6716      17.54      0.20     -62    36
# Comp:  2             [SII]6731      12.57      0.20     -62    36
# Comp:  2              HeII4687      0.000      0.20     -62    36
# Comp:  2               HeI5876      3.660      0.20     -62    36
# Comp:  2          [OIII]5007_d      41.91      0.25     -62    36
# Comp:  2            [OI]6300_d      2.506      0.25     -62    36
# Comp:  2           [NII]6583_d      23.81      0.25     -62    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -61        32
#  comp.  2:       -53        47
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.10      0.19     -61    32
# Comp:  1                Halpha      96.87      0.19     -61    32
# Comp:  2             [SII]6716      18.22      0.20     -53    47
# Comp:  2             [SII]6731      14.32      0.20     -53    47
# Comp:  2              HeII4687      0.000      0.20     -53    47
# Comp:  2               HeI5876      3.212      0.20     -53    47
# Comp:  2          [OIII]5007_d      42.57      0.26     -53    47
# Comp:  2            [OI]6300_d      2.516      0.26     -53    47
# Comp:  2           [NII]6583_d      24.85      0.26     -53    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        27
#  comp.  1:       -59        35
#  comp.  2:       -56        31
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.15      0.20     -59    35
# Comp:  1                Halpha      98.27      0.20     -59    35
# Comp:  2             [SII]6716      18.24      0.19     -56    31
# Comp:  2             [SII]6731      12.72      0.19     -56    31
# Comp:  2              HeII4687      0.000      0.19     -56    31
# Comp:  2               HeI5876      2.721      0.19     -56    31
# Comp:  2          [OIII]5007_d      39.71      0.24     -56    31
# Comp:  2            [OI]6300_d      2.687      0.24     -56    31
# Comp:  2           [NII]6583_d      22.65      0.24     -56    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -58        30
#  comp.  2:       -62        30
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.45      0.19     -58    30
# Comp:  1                Halpha      95.56      0.19     -58    30
# Comp:  2             [SII]6716      17.27      0.19     -62    30
# Comp:  2             [SII]6731      13.46      0.19     -62    30
# Comp:  2              HeII4687      0.000      0.19     -62    30
# Comp:  2               HeI5876      2.794      0.19     -62    30
# Comp:  2          [OIII]5007_d      41.45      0.24     -62    30
# Comp:  2            [OI]6300_d      2.613      0.24     -62    30
# Comp:  2           [NII]6583_d      22.70      0.24     -62    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        29
#  comp.  1:       -59        27
#  comp.  2:       -56        29
# chi2/DOF: 1.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.99      0.19     -59    27
# Comp:  1                Halpha      95.31      0.19     -59    27
# Comp:  2             [SII]6716      16.65      0.19     -56    29
# Comp:  2             [SII]6731      12.16      0.19     -56    29
# Comp:  2              HeII4687      0.000      0.19     -56    29
# Comp:  2               HeI5876      2.666      0.19     -56    29
# Comp:  2          [OIII]5007_d      39.07      0.24     -56    29
# Comp:  2            [OI]6300_d      2.573      0.24     -56    29
# Comp:  2           [NII]6583_d      23.56      0.24     -56    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -59        30
#  comp.  2:       -57        34
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.89      0.19     -59    30
# Comp:  1                Halpha      95.54      0.19     -59    30
# Comp:  2             [SII]6716      17.22      0.20     -57    34
# Comp:  2             [SII]6731      11.78      0.20     -57    34
# Comp:  2              HeII4687     0.3768      0.20     -57    34
# Comp:  2               HeI5876      2.586      0.20     -57    34
# Comp:  2          [OIII]5007_d      39.35      0.25     -57    34
# Comp:  2            [OI]6300_d      3.074      0.25     -57    34
# Comp:  2           [NII]6583_d      23.54      0.25     -57    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -60        36
#  comp.  2:       -61        40
# chi2/DOF: 1.211; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.67      0.20     -60    36
# Comp:  1                Halpha      98.49      0.20     -60    36
# Comp:  2             [SII]6716      18.61      0.20     -61    40
# Comp:  2             [SII]6731      14.01      0.20     -61    40
# Comp:  2              HeII4687     0.4042      0.20     -61    40
# Comp:  2               HeI5876      3.227      0.20     -61    40
# Comp:  2          [OIII]5007_d      42.07      0.25     -61    40
# Comp:  2            [OI]6300_d      3.034      0.25     -61    40
# Comp:  2           [NII]6583_d      23.76      0.25     -61    40
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.02221162, 1.7542033 , 1.16862381, 1.15728858, 0.14922501,
#        0.32631185, 2.09279811, 0.3130162 , 0.86993383])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 30.26628194, 132.08746745,  24.67533405,  18.05101957,
#          0.        ,   3.86377229,  43.99713314,   3.52239142,
#         32.85592013])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_16_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_16", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_16_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_16_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_16_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  1.941906    0.129747
# 1        Halpha  8.474824    0.112551
# 2     [SII]6716  1.583187    0.074980
# 3     [SII]6731  1.158166    0.074252
# 4      HeII4687  0.000000    0.009574
# 5       HeI5876  0.247902    0.020936
# 6  [OIII]5007_d  2.822887    0.134275
# 7    [OI]6300_d  0.225999    0.020083
# 8   [NII]6583_d  2.108059    0.055816
#           Name      Flux  Error_flux
# 0        Hbeta  1.941906    0.129747
# 1       Halpha  8.474824    0.112551
# 2    [SII]6716  1.583187    0.074980
# 3    [SII]6731  1.158166    0.074252
# 4     HeII4687  0.000000    0.009574
# 5      HeI5876  0.247902    0.020936
# 6   [OIII]4959  0.705722    0.134275
# 7   [OIII]5007  2.117165    0.134275
# 8     [OI]6300  0.169499    0.020083
# 9     [OI]6364  0.056500    0.020083
# 10   [NII]6548  0.527015    0.055816
# 11   [NII]6583  1.581044    0.055816

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06416069427427962
