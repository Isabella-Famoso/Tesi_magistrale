# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_19.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_19']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.0261018  0.02827028 0.03575111 ... 0.01810726 0.01690647 0.01631003] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        22
# chi2/DOF: 0.04120; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
# chi2/DOF: 0.02536; DOF: 1907; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        47
#  comp.  1:       -61        39
#  comp.  2:       -52        54
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.531      0.40     -61    39
# Comp:  1                Halpha      21.93      0.40     -61    39
# Comp:  2             [SII]6716      7.817      0.42     -52    54
# Comp:  2             [SII]6731      4.665      0.42     -52    54
# Comp:  2              HeII4687      0.000      0.42     -52    54
# Comp:  2               HeI5876     0.2353      0.42     -52    54
# Comp:  2          [OIII]5007_d      11.27      0.53     -52    54
# Comp:  2            [OI]6300_d      3.493      0.53     -52    54
# Comp:  2           [NII]6583_d      7.715      0.53     -52    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        41
#  comp.  1:       -61        33
#  comp.  2:       -57        40
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.864      0.39     -61    33
# Comp:  1                Halpha      20.79      0.39     -61    33
# Comp:  2             [SII]6716      7.614      0.40     -57    40
# Comp:  2             [SII]6731      4.228      0.40     -57    40
# Comp:  2              HeII4687      0.000      0.40     -57    40
# Comp:  2               HeI5876     0.2874      0.40     -57    40
# Comp:  2          [OIII]5007_d      11.81      0.51     -57    40
# Comp:  2            [OI]6300_d      3.078      0.51     -57    40
# Comp:  2           [NII]6583_d      6.623      0.51     -57    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        65
#  comp.  1:       -62        35
#  comp.  2:       -52        45
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.768      0.40     -62    35
# Comp:  1                Halpha      21.31      0.40     -62    35
# Comp:  2             [SII]6716      7.848      0.41     -52    45
# Comp:  2             [SII]6731      4.484      0.41     -52    45
# Comp:  2              HeII4687     0.3809      0.41     -52    45
# Comp:  2               HeI5876     0.1169      0.41     -52    45
# Comp:  2          [OIII]5007_d      11.20      0.52     -52    45
# Comp:  2            [OI]6300_d      3.203      0.52     -52    45
# Comp:  2           [NII]6583_d      6.694      0.52     -52    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22       105
#  comp.  1:       -61        37
#  comp.  2:       -52        33
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.618      0.40     -61    37
# Comp:  1                Halpha      21.38      0.40     -61    37
# Comp:  2             [SII]6716      7.336      0.40     -52    33
# Comp:  2             [SII]6731      4.073      0.40     -52    33
# Comp:  2              HeII4687      0.000      0.40     -52    33
# Comp:  2               HeI5876     0.1681      0.40     -52    33
# Comp:  2          [OIII]5007_d      9.256      0.50     -52    33
# Comp:  2            [OI]6300_d      3.349      0.50     -52    33
# Comp:  2           [NII]6583_d      6.945      0.50     -52    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        58
#  comp.  1:       -62        36
#  comp.  2:       -55        33
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.633      0.40     -62    36
# Comp:  1                Halpha      21.44      0.40     -62    36
# Comp:  2             [SII]6716      7.333      0.39     -55    33
# Comp:  2             [SII]6731      4.298      0.39     -55    33
# Comp:  2              HeII4687     0.1739      0.39     -55    33
# Comp:  2               HeI5876     0.1874      0.39     -55    33
# Comp:  2          [OIII]5007_d      9.590      0.50     -55    33
# Comp:  2            [OI]6300_d      2.857      0.50     -55    33
# Comp:  2           [NII]6583_d      6.753      0.50     -55    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        66
#  comp.  1:       -59        37
#  comp.  2:       -56        42
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.917      0.40     -59    37
# Comp:  1                Halpha      21.65      0.40     -59    37
# Comp:  2             [SII]6716      7.785      0.41     -56    42
# Comp:  2             [SII]6731      4.410      0.41     -56    42
# Comp:  2              HeII4687      0.000      0.41     -56    42
# Comp:  2               HeI5876     0.3437      0.41     -56    42
# Comp:  2          [OIII]5007_d      12.43      0.51     -56    42
# Comp:  2            [OI]6300_d      2.617      0.51     -56    42
# Comp:  2           [NII]6583_d      6.449      0.51     -56    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        30
#  comp.  1:       -62        32
#  comp.  2:       -53        35
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.070      0.39     -62    32
# Comp:  1                Halpha      21.20      0.39     -62    32
# Comp:  2             [SII]6716      7.619      0.40     -53    35
# Comp:  2             [SII]6731      4.331      0.40     -53    35
# Comp:  2              HeII4687      0.000      0.40     -53    35
# Comp:  2               HeI5876     0.2541      0.40     -53    35
# Comp:  2          [OIII]5007_d      10.52      0.50     -53    35
# Comp:  2            [OI]6300_d      3.329      0.50     -53    35
# Comp:  2           [NII]6583_d      6.543      0.50     -53    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        85
#  comp.  1:       -61        32
#  comp.  2:       -56        36
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.682      0.39     -61    32
# Comp:  1                Halpha      21.27      0.39     -61    32
# Comp:  2             [SII]6716      7.647      0.40     -56    36
# Comp:  2             [SII]6731      4.649      0.40     -56    36
# Comp:  2              HeII4687     0.3831      0.40     -56    36
# Comp:  2               HeI5876     0.3610      0.40     -56    36
# Comp:  2          [OIII]5007_d      11.36      0.50     -56    36
# Comp:  2            [OI]6300_d      2.579      0.50     -56    36
# Comp:  2           [NII]6583_d      6.692      0.50     -56    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        42
#  comp.  1:       -63        31
#  comp.  2:       -56        47
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.092      0.39     -63    31
# Comp:  1                Halpha      20.89      0.39     -63    31
# Comp:  2             [SII]6716      7.786      0.41     -56    47
# Comp:  2             [SII]6731      4.587      0.41     -56    47
# Comp:  2              HeII4687     0.3343      0.41     -56    47
# Comp:  2               HeI5876     0.2392      0.41     -56    47
# Comp:  2          [OIII]5007_d      11.32      0.52     -56    47
# Comp:  2            [OI]6300_d      2.333      0.52     -56    47
# Comp:  2           [NII]6583_d      6.654      0.52     -56    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9       112
#  comp.  1:       -62        31
#  comp.  2:       -58        30
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.846      0.39     -62    31
# Comp:  1                Halpha      21.08      0.39     -62    31
# Comp:  2             [SII]6716      7.238      0.39     -58    30
# Comp:  2             [SII]6731      4.241      0.39     -58    30
# Comp:  2              HeII4687    0.01388      0.39     -58    30
# Comp:  2               HeI5876     0.2975      0.39     -58    30
# Comp:  2          [OIII]5007_d      10.84      0.49     -58    30
# Comp:  2            [OI]6300_d      3.038      0.49     -58    30
# Comp:  2           [NII]6583_d      6.761      0.49     -58    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        73
#  comp.  1:       -58        37
#  comp.  2:       -56        39
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.968      0.40     -58    37
# Comp:  1                Halpha      21.52      0.40     -58    37
# Comp:  2             [SII]6716      7.517      0.40     -56    39
# Comp:  2             [SII]6731      4.232      0.40     -56    39
# Comp:  2              HeII4687    0.07068      0.40     -56    39
# Comp:  2               HeI5876     0.2342      0.40     -56    39
# Comp:  2          [OIII]5007_d      11.47      0.51     -56    39
# Comp:  2            [OI]6300_d      2.642      0.51     -56    39
# Comp:  2           [NII]6583_d      6.846      0.51     -56    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -60        33
#  comp.  2:       -53        38
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.754      0.39     -60    33
# Comp:  1                Halpha      21.20      0.39     -60    33
# Comp:  2             [SII]6716      7.734      0.40     -53    38
# Comp:  2             [SII]6731      4.258      0.40     -53    38
# Comp:  2              HeII4687      0.000      0.40     -53    38
# Comp:  2               HeI5876     0.1711      0.40     -53    38
# Comp:  2          [OIII]5007_d      11.67      0.51     -53    38
# Comp:  2            [OI]6300_d      2.968      0.51     -53    38
# Comp:  2           [NII]6583_d      6.577      0.51     -53    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -59        35
#  comp.  2:       -56        32
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.741      0.40     -59    35
# Comp:  1                Halpha      21.40      0.40     -59    35
# Comp:  2             [SII]6716      7.430      0.39     -56    32
# Comp:  2             [SII]6731      4.323      0.39     -56    32
# Comp:  2              HeII4687      0.000      0.39     -56    32
# Comp:  2               HeI5876     0.1941      0.39     -56    32
# Comp:  2          [OIII]5007_d      10.82      0.50     -56    32
# Comp:  2            [OI]6300_d      2.624      0.50     -56    32
# Comp:  2           [NII]6583_d      6.806      0.50     -56    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        79
#  comp.  1:       -60        35
#  comp.  2:       -58        33
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.242      0.40     -60    35
# Comp:  1                Halpha      21.47      0.40     -60    35
# Comp:  2             [SII]6716      7.347      0.40     -58    33
# Comp:  2             [SII]6731      4.189      0.40     -58    33
# Comp:  2              HeII4687     0.2728      0.40     -58    33
# Comp:  2               HeI5876     0.2037      0.40     -58    33
# Comp:  2          [OIII]5007_d      10.89      0.50     -58    33
# Comp:  2            [OI]6300_d      3.412      0.50     -58    33
# Comp:  2           [NII]6583_d      6.958      0.50     -58    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        64
#  comp.  1:       -63        34
#  comp.  2:       -53        45
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.633      0.40     -63    34
# Comp:  1                Halpha      21.18      0.40     -63    34
# Comp:  2             [SII]6716      7.625      0.41     -53    45
# Comp:  2             [SII]6731      4.717      0.41     -53    45
# Comp:  2              HeII4687      0.000      0.41     -53    45
# Comp:  2               HeI5876     0.2874      0.41     -53    45
# Comp:  2          [OIII]5007_d      11.68      0.52     -53    45
# Comp:  2            [OI]6300_d      3.189      0.52     -53    45
# Comp:  2           [NII]6583_d      6.903      0.52     -53    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        40
#  comp.  1:       -63        35
#  comp.  2:       -53        50
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.032      0.40     -63    35
# Comp:  1                Halpha      21.37      0.40     -63    35
# Comp:  2             [SII]6716      8.028      0.42     -53    50
# Comp:  2             [SII]6731      4.833      0.42     -53    50
# Comp:  2              HeII4687     0.3131      0.42     -53    50
# Comp:  2               HeI5876     0.1139      0.42     -53    50
# Comp:  2          [OIII]5007_d      10.99      0.53     -53    50
# Comp:  2            [OI]6300_d      3.431      0.53     -53    50
# Comp:  2           [NII]6583_d      7.000      0.53     -53    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        74
#  comp.  1:       -61        30
#  comp.  2:       -53        47
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.558      0.39     -61    30
# Comp:  1                Halpha      20.82      0.39     -61    30
# Comp:  2             [SII]6716      7.805      0.41     -53    47
# Comp:  2             [SII]6731      4.803      0.41     -53    47
# Comp:  2              HeII4687      0.000      0.41     -53    47
# Comp:  2               HeI5876     0.1516      0.41     -53    47
# Comp:  2          [OIII]5007_d      11.09      0.52     -53    47
# Comp:  2            [OI]6300_d      2.910      0.52     -53    47
# Comp:  2           [NII]6583_d      6.759      0.52     -53    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        99
#  comp.  1:       -60        36
#  comp.  2:       -56        30
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.121      0.40     -60    36
# Comp:  1                Halpha      21.62      0.40     -60    36
# Comp:  2             [SII]6716      7.544      0.39     -56    30
# Comp:  2             [SII]6731      4.149      0.39     -56    30
# Comp:  2              HeII4687      0.000      0.39     -56    30
# Comp:  2               HeI5876     0.2200      0.39     -56    30
# Comp:  2          [OIII]5007_d      10.40      0.49     -56    30
# Comp:  2            [OI]6300_d      3.149      0.49     -56    30
# Comp:  2           [NII]6583_d      6.472      0.49     -56    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        39
#  comp.  1:       -60        36
#  comp.  2:       -51        39
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.748      0.40     -60    36
# Comp:  1                Halpha      21.31      0.40     -60    36
# Comp:  2             [SII]6716      7.520      0.40     -51    39
# Comp:  2             [SII]6731      4.462      0.40     -51    39
# Comp:  2              HeII4687      0.000      0.40     -51    39
# Comp:  2               HeI5876     0.2484      0.40     -51    39
# Comp:  2          [OIII]5007_d      11.99      0.51     -51    39
# Comp:  2            [OI]6300_d      2.664      0.51     -51    39
# Comp:  2           [NII]6583_d      6.799      0.51     -51    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        60
#  comp.  1:       -60        39
#  comp.  2:       -49        48
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.818      0.40     -60    39
# Comp:  1                Halpha      22.09      0.40     -60    39
# Comp:  2             [SII]6716      7.871      0.41     -49    48
# Comp:  2             [SII]6731      4.721      0.41     -49    48
# Comp:  2              HeII4687      0.000      0.41     -49    48
# Comp:  2               HeI5876    0.08679      0.41     -49    48
# Comp:  2          [OIII]5007_d      10.69      0.52     -49    48
# Comp:  2            [OI]6300_d      3.323      0.52     -49    48
# Comp:  2           [NII]6583_d      6.862      0.52     -49    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        26
#  comp.  1:       -61        38
#  comp.  2:       -58        37
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.320      0.40     -61    38
# Comp:  1                Halpha      22.31      0.40     -61    38
# Comp:  2             [SII]6716      7.568      0.40     -58    37
# Comp:  2             [SII]6731      4.284      0.40     -58    37
# Comp:  2              HeII4687      0.000      0.40     -58    37
# Comp:  2               HeI5876     0.2883      0.40     -58    37
# Comp:  2          [OIII]5007_d      10.33      0.51     -58    37
# Comp:  2            [OI]6300_d      2.570      0.51     -58    37
# Comp:  2           [NII]6583_d      6.436      0.51     -58    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        42
#  comp.  1:       -62        37
#  comp.  2:       -51        41
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.129      0.40     -62    37
# Comp:  1                Halpha      21.42      0.40     -62    37
# Comp:  2             [SII]6716      7.601      0.41     -51    41
# Comp:  2             [SII]6731      4.524      0.41     -51    41
# Comp:  2              HeII4687     0.2860      0.41     -51    41
# Comp:  2               HeI5876     0.2647      0.41     -51    41
# Comp:  2          [OIII]5007_d      10.82      0.51     -51    41
# Comp:  2            [OI]6300_d      2.733      0.51     -51    41
# Comp:  2           [NII]6583_d      7.206      0.51     -51    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        20
#  comp.  1:       -62        36
#  comp.  2:       -54        43
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.935      0.40     -62    36
# Comp:  1                Halpha      21.50      0.40     -62    36
# Comp:  2             [SII]6716      7.726      0.41     -54    43
# Comp:  2             [SII]6731      4.441      0.41     -54    43
# Comp:  2              HeII4687      0.000      0.41     -54    43
# Comp:  2               HeI5876     0.1248      0.41     -54    43
# Comp:  2          [OIII]5007_d      12.54      0.51     -54    43
# Comp:  2            [OI]6300_d      3.210      0.51     -54    43
# Comp:  2           [NII]6583_d      7.035      0.51     -54    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20        26
#  comp.  1:       -60        31
#  comp.  2:       -54        34
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.113      0.39     -60    31
# Comp:  1                Halpha      20.94      0.39     -60    31
# Comp:  2             [SII]6716      7.425      0.40     -54    34
# Comp:  2             [SII]6731      4.470      0.40     -54    34
# Comp:  2              HeII4687      0.000      0.40     -54    34
# Comp:  2               HeI5876     0.3443      0.40     -54    34
# Comp:  2          [OIII]5007_d      10.90      0.50     -54    34
# Comp:  2            [OI]6300_d      3.148      0.50     -54    34
# Comp:  2           [NII]6583_d      6.778      0.50     -54    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        66
#  comp.  1:       -63        34
#  comp.  2:       -55        37
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.938      0.40     -63    34
# Comp:  1                Halpha      20.98      0.40     -63    34
# Comp:  2             [SII]6716      7.558      0.40     -55    37
# Comp:  2             [SII]6731      4.215      0.40     -55    37
# Comp:  2              HeII4687     0.3722      0.40     -55    37
# Comp:  2               HeI5876     0.1548      0.40     -55    37
# Comp:  2          [OIII]5007_d      10.86      0.50     -55    37
# Comp:  2            [OI]6300_d      2.562      0.50     -55    37
# Comp:  2           [NII]6583_d      6.877      0.50     -55    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -61        38
#  comp.  2:       -55        39
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.801      0.40     -61    38
# Comp:  1                Halpha      22.22      0.40     -61    38
# Comp:  2             [SII]6716      7.531      0.40     -55    39
# Comp:  2             [SII]6731      4.707      0.40     -55    39
# Comp:  2              HeII4687      0.000      0.40     -55    39
# Comp:  2               HeI5876     0.2206      0.40     -55    39
# Comp:  2          [OIII]5007_d      10.48      0.51     -55    39
# Comp:  2            [OI]6300_d      2.550      0.51     -55    39
# Comp:  2           [NII]6583_d      6.559      0.51     -55    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        33
#  comp.  1:       -61        35
#  comp.  2:       -55        47
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.735      0.40     -61    35
# Comp:  1                Halpha      21.27      0.40     -61    35
# Comp:  2             [SII]6716      7.906      0.41     -55    47
# Comp:  2             [SII]6731      4.384      0.41     -55    47
# Comp:  2              HeII4687     0.1662      0.41     -55    47
# Comp:  2               HeI5876     0.1400      0.41     -55    47
# Comp:  2          [OIII]5007_d      10.65      0.52     -55    47
# Comp:  2            [OI]6300_d      2.781      0.52     -55    47
# Comp:  2           [NII]6583_d      6.951      0.52     -55    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        83
#  comp.  1:       -60        37
#  comp.  2:       -53        38
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.753      0.40     -60    37
# Comp:  1                Halpha      21.95      0.40     -60    37
# Comp:  2             [SII]6716      7.576      0.40     -53    38
# Comp:  2             [SII]6731      4.638      0.40     -53    38
# Comp:  2              HeII4687      0.000      0.40     -53    38
# Comp:  2               HeI5876     0.3743      0.40     -53    38
# Comp:  2          [OIII]5007_d      10.10      0.51     -53    38
# Comp:  2            [OI]6300_d      3.059      0.51     -53    38
# Comp:  2           [NII]6583_d      6.509      0.51     -53    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -58        38
#  comp.  2:       -55        32
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.295      0.40     -58    38
# Comp:  1                Halpha      21.58      0.40     -58    38
# Comp:  2             [SII]6716      7.434      0.39     -55    32
# Comp:  2             [SII]6731      4.370      0.39     -55    32
# Comp:  2              HeII4687      0.000      0.39     -55    32
# Comp:  2               HeI5876    0.05327      0.39     -55    32
# Comp:  2          [OIII]5007_d      11.10      0.50     -55    32
# Comp:  2            [OI]6300_d      3.379      0.50     -55    32
# Comp:  2           [NII]6583_d      6.559      0.50     -55    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27        82
#  comp.  1:       -60        34
#  comp.  2:       -55        32
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.202      0.40     -60    34
# Comp:  1                Halpha      21.14      0.40     -60    34
# Comp:  2             [SII]6716      7.525      0.39     -55    32
# Comp:  2             [SII]6731      4.378      0.39     -55    32
# Comp:  2              HeII4687     0.4414      0.39     -55    32
# Comp:  2               HeI5876     0.2921      0.39     -55    32
# Comp:  2          [OIII]5007_d      10.66      0.50     -55    32
# Comp:  2            [OI]6300_d      2.854      0.50     -55    32
# Comp:  2           [NII]6583_d      6.589      0.50     -55    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        64
#  comp.  1:       -61        36
#  comp.  2:       -55        35
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.165      0.40     -61    36
# Comp:  1                Halpha      21.19      0.40     -61    36
# Comp:  2             [SII]6716      7.319      0.40     -55    35
# Comp:  2             [SII]6731      4.326      0.40     -55    35
# Comp:  2              HeII4687     0.1318      0.40     -55    35
# Comp:  2               HeI5876     0.1969      0.40     -55    35
# Comp:  2          [OIII]5007_d      11.04      0.50     -55    35
# Comp:  2            [OI]6300_d      2.713      0.50     -55    35
# Comp:  2           [NII]6583_d      6.496      0.50     -55    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        39
#  comp.  1:       -61        36
#  comp.  2:       -54        40
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.223      0.40     -61    36
# Comp:  1                Halpha      21.64      0.40     -61    36
# Comp:  2             [SII]6716      7.567      0.40     -54    40
# Comp:  2             [SII]6731      4.490      0.40     -54    40
# Comp:  2              HeII4687      0.000      0.40     -54    40
# Comp:  2               HeI5876    0.09306      0.40     -54    40
# Comp:  2          [OIII]5007_d      11.53      0.51     -54    40
# Comp:  2            [OI]6300_d      2.331      0.51     -54    40
# Comp:  2           [NII]6583_d      6.852      0.51     -54    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        48
#  comp.  1:       -62        31
#  comp.  2:       -55        37
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.306      0.39     -62    31
# Comp:  1                Halpha      21.24      0.39     -62    31
# Comp:  2             [SII]6716      7.582      0.40     -55    37
# Comp:  2             [SII]6731      4.664      0.40     -55    37
# Comp:  2              HeII4687      0.000      0.40     -55    37
# Comp:  2               HeI5876     0.3229      0.40     -55    37
# Comp:  2          [OIII]5007_d      11.84      0.51     -55    37
# Comp:  2            [OI]6300_d      2.987      0.51     -55    37
# Comp:  2           [NII]6583_d      6.850      0.51     -55    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        52
#  comp.  1:       -60        36
#  comp.  2:       -55        39
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.321      0.40     -60    36
# Comp:  1                Halpha      21.46      0.40     -60    36
# Comp:  2             [SII]6716      7.517      0.40     -55    39
# Comp:  2             [SII]6731      4.363      0.40     -55    39
# Comp:  2              HeII4687      0.000      0.40     -55    39
# Comp:  2               HeI5876     0.2517      0.40     -55    39
# Comp:  2          [OIII]5007_d      10.77      0.51     -55    39
# Comp:  2            [OI]6300_d      2.600      0.51     -55    39
# Comp:  2           [NII]6583_d      6.564      0.51     -55    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        40
#  comp.  1:       -58        39
#  comp.  2:       -51        35
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.730      0.40     -58    39
# Comp:  1                Halpha      22.21      0.40     -58    39
# Comp:  2             [SII]6716      7.457      0.40     -51    35
# Comp:  2             [SII]6731      4.436      0.40     -51    35
# Comp:  2              HeII4687      0.000      0.40     -51    35
# Comp:  2               HeI5876     0.3365      0.40     -51    35
# Comp:  2          [OIII]5007_d      10.39      0.50     -51    35
# Comp:  2            [OI]6300_d      2.686      0.50     -51    35
# Comp:  2           [NII]6583_d      6.808      0.50     -51    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        39
#  comp.  1:       -63        32
#  comp.  2:       -51        42
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.571      0.39     -63    32
# Comp:  1                Halpha      20.85      0.39     -63    32
# Comp:  2             [SII]6716      7.741      0.41     -51    42
# Comp:  2             [SII]6731      4.401      0.41     -51    42
# Comp:  2              HeII4687      0.000      0.41     -51    42
# Comp:  2               HeI5876     0.3501      0.41     -51    42
# Comp:  2          [OIII]5007_d      10.93      0.51     -51    42
# Comp:  2            [OI]6300_d      3.621      0.51     -51    42
# Comp:  2           [NII]6583_d      6.688      0.51     -51    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        37
#  comp.  1:       -61        35
#  comp.  2:       -54        33
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.748      0.40     -61    35
# Comp:  1                Halpha      21.38      0.40     -61    35
# Comp:  2             [SII]6716      7.433      0.39     -54    33
# Comp:  2             [SII]6731      4.262      0.39     -54    33
# Comp:  2              HeII4687    0.09669      0.39     -54    33
# Comp:  2               HeI5876    0.04889      0.39     -54    33
# Comp:  2          [OIII]5007_d      9.193      0.50     -54    33
# Comp:  2            [OI]6300_d      2.520      0.50     -54    33
# Comp:  2           [NII]6583_d      6.964      0.50     -54    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -61        39
#  comp.  2:       -53        35
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.357      0.40     -61    39
# Comp:  1                Halpha      21.90      0.40     -61    39
# Comp:  2             [SII]6716      7.492      0.40     -53    35
# Comp:  2             [SII]6731      4.462      0.40     -53    35
# Comp:  2              HeII4687     0.3569      0.40     -53    35
# Comp:  2               HeI5876     0.2837      0.40     -53    35
# Comp:  2          [OIII]5007_d      11.72      0.50     -53    35
# Comp:  2            [OI]6300_d      2.699      0.50     -53    35
# Comp:  2           [NII]6583_d      6.860      0.50     -53    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        32
#  comp.  1:       -61        33
#  comp.  2:       -58        20
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.150      0.39     -61    33
# Comp:  1                Halpha      20.94      0.39     -61    33
# Comp:  2             [SII]6716      7.096      0.38     -58    20
# Comp:  2             [SII]6731      4.288      0.38     -58    20
# Comp:  2              HeII4687     0.3307      0.38     -58    20
# Comp:  2               HeI5876     0.2843      0.38     -58    20
# Comp:  2          [OIII]5007_d      10.69      0.48     -58    20
# Comp:  2            [OI]6300_d      2.472      0.48     -58    20
# Comp:  2           [NII]6583_d      6.187      0.48     -58    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -58        35
#  comp.  2:       -51        38
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.492      0.40     -58    35
# Comp:  1                Halpha      21.58      0.40     -58    35
# Comp:  2             [SII]6716      7.720      0.40     -51    38
# Comp:  2             [SII]6731      4.459      0.40     -51    38
# Comp:  2              HeII4687     0.4739      0.40     -51    38
# Comp:  2               HeI5876     0.2622      0.40     -51    38
# Comp:  2          [OIII]5007_d      11.10      0.51     -51    38
# Comp:  2            [OI]6300_d      3.018      0.51     -51    38
# Comp:  2           [NII]6583_d      6.799      0.51     -51    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        14
#  comp.  1:       -61        33
#  comp.  2:       -53        41
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.165      0.40     -61    33
# Comp:  1                Halpha      21.29      0.40     -61    33
# Comp:  2             [SII]6716      7.670      0.41     -53    41
# Comp:  2             [SII]6731      4.584      0.41     -53    41
# Comp:  2              HeII4687    0.04645      0.41     -53    41
# Comp:  2               HeI5876     0.2444      0.41     -53    41
# Comp:  2          [OIII]5007_d      11.04      0.51     -53    41
# Comp:  2            [OI]6300_d      3.041      0.51     -53    41
# Comp:  2           [NII]6583_d      6.657      0.51     -53    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        38
#  comp.  1:       -60        32
#  comp.  2:       -52        40
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.649      0.39     -60    32
# Comp:  1                Halpha      20.58      0.39     -60    32
# Comp:  2             [SII]6716      7.672      0.40     -52    40
# Comp:  2             [SII]6731      4.343      0.40     -52    40
# Comp:  2              HeII4687      0.000      0.40     -52    40
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.307      0.40     -61    35
# Comp:  1                Halpha      21.02      0.40     -61    35
# Comp:  2             [SII]6716      7.352      0.39     -53    28
# Comp:  2             [SII]6731      4.283      0.39     -53    28
# Comp:  2              HeII4687      0.000      0.39     -53    28
# Comp:  2               HeI5876     0.4987      0.39     -53    28
# Comp:  2          [OIII]5007_d      11.31      0.49     -53    28
# Comp:  2            [OI]6300_d      3.162      0.49     -53    28
# Comp:  2           [NII]6583_d      6.780      0.49     -53    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        53
#  comp.  1:       -61        42
#  comp.  2:       -50        31
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.614      0.41     -61    42
# Comp:  1                Halpha      21.87      0.41     -61    42
# Comp:  2             [SII]6716      7.259      0.39     -50    31
# Comp:  2             [SII]6731      4.103      0.39     -50    31
# Comp:  2              HeII4687      0.000      0.39     -50    31
# Comp:  2               HeI5876     0.2411      0.39     -50    31
# Comp:  2          [OIII]5007_d      11.40      0.50     -50    31
# Comp:  2            [OI]6300_d      3.253      0.50     -50    31
# Comp:  2           [NII]6583_d      6.884      0.50     -50    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        18
#  comp.  1:       -62        35
#  comp.  2:       -51        38
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.844      0.40     -62    35
# Comp:  1                Halpha      21.23      0.40     -62    35
# Comp:  2             [SII]6716      7.533      0.40     -51    38
# Comp:  2             [SII]6731      4.591      0.40     -51    38
# Comp:  2              HeII4687      0.000      0.40     -51    38
# Comp:  2               HeI5876     0.2157      0.40     -51    38
# Comp:  2          [OIII]5007_d      11.20      0.51     -51    38
# Comp:  2            [OI]6300_d      3.099      0.51     -51    38
# Comp:  2           [NII]6583_d      6.683      0.51     -51    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        88
#  comp.  1:       -62        34
#  comp.  2:       -59        30
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.149      0.40     -62    34
# Comp:  1                Halpha      21.42      0.40     -62    34
# Comp:  2             [SII]6716      7.383      0.39     -59    30
# Comp:  2             [SII]6731      4.326      0.39     -59    30
# Comp:  2              HeII4687     0.4284      0.39     -59    30
# Comp:  2               HeI5876    0.09287      0.39     -59    30
# Comp:  2          [OIII]5007_d      9.618      0.49     -59    30
# Comp:  2            [OI]6300_d      3.017      0.49     -59    30
# Comp:  2           [NII]6583_d      6.298      0.49     -59    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        62
#  comp.  1:       -61        35
#  comp.  2:       -57        38
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.451      0.40     -61    35
# Comp:  1                Halpha      21.52      0.40     -61    35
# Comp:  2             [SII]6716      7.681      0.40     -57    38
# Comp:  2             [SII]6731      4.504      0.40     -57    38
# Comp:  2              HeII4687      0.000      0.40     -57    38
# Comp:  2               HeI5876     0.1479      0.40     -57    38
# Comp:  2          [OIII]5007_d      10.80      0.51     -57    38
# Comp:  2            [OI]6300_d      3.084      0.51     -57    38
# Comp:  2           [NII]6583_d      6.527      0.51     -57    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7       107
#  comp.  1:       -61        37
#  comp.  2:       -55        33
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.684      0.40     -61    37
# Comp:  1                Halpha      21.51      0.40     -61    37
# Comp:  2             [SII]6716      7.512      0.39     -55    33
# Comp:  2             [SII]6731      4.451      0.39     -55    33
# Comp:  2              HeII4687     0.1166      0.39     -55    33
# Comp:  2               HeI5876     0.2514      0.39     -55    33
# Comp:  2          [OIII]5007_d      9.776      0.50     -55    33
# Comp:  2            [OI]6300_d      2.662      0.50     -55    33
# Comp:  2           [NII]6583_d      7.074      0.50     -55    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -60        34
#  comp.  2:       -45        46
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.088      0.40     -60    34
# Comp:  1                Halpha      21.11      0.40     -60    34
# Comp:  2             [SII]6716      7.658      0.41     -45    46
# Comp:  2             [SII]6731      4.703      0.41     -45    46
# Comp:  2              HeII4687      0.000      0.41     -45    46
# Comp:  2               HeI5876     0.1030      0.41     -45    46
# Comp:  2          [OIII]5007_d      11.05      0.52     -45    46
# Comp:  2            [OI]6300_d      3.309      0.52     -45    46
# Comp:  2           [NII]6583_d      7.027      0.52     -45    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        84
#  comp.  1:       -60        42
#  comp.  2:       -59        45
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.277      0.41     -60    42
# Comp:  1                Halpha      22.13      0.41     -60    42
# Comp:  2             [SII]6716      7.812      0.41     -59    45
# Comp:  2             [SII]6731      4.388      0.41     -59    45
# Comp:  2              HeII4687      0.000      0.41     -59    45
# Comp:  2               HeI5876     0.4271      0.41     -59    45
# Comp:  2          [OIII]5007_d      10.61      0.52     -59    45
# Comp:  2            [OI]6300_d      2.465      0.52     -59    45
# Comp:  2           [NII]6583_d      6.612      0.52     -59    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -61        39
#  comp.  2:       -54        46
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.916      0.40     -61    39
# Comp:  1                Halpha      21.72      0.40     -61    39
# Comp:  2             [SII]6716      7.876      0.41     -54    46
# Comp:  2             [SII]6731      4.740      0.41     -54    46
# Comp:  2              HeII4687   0.008232      0.41     -54    46
# Comp:  2               HeI5876     0.2256      0.41     -54    46
# Comp:  2          [OIII]5007_d      10.47      0.52     -54    46
# Comp:  2            [OI]6300_d      2.808      0.52     -54    46
# Comp:  2           [NII]6583_d      7.157      0.52     -54    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        73
#  comp.  1:       -62        39
#  comp.  2:       -52        37
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.397      0.40     -62    39
# Comp:  1                Halpha      21.34      0.40     -62    39
# Comp:  2             [SII]6716      7.487      0.40     -52    37
# Comp:  2             [SII]6731      4.441      0.40     -52    37
# Comp:  2              HeII4687      0.000      0.40     -52    37
# Comp:  2               HeI5876     0.1927      0.40     -52    37
# Comp:  2          [OIII]5007_d      10.18      0.50     -52    37
# Comp:  2            [OI]6300_d      2.830      0.50     -52    37
# Comp:  2           [NII]6583_d      6.456      0.50     -52    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -62        31
#  comp.  2:       -58        32
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.704      0.39     -62    31
# Comp:  1                Halpha      20.65      0.39     -62    31
# Comp:  2             [SII]6716      7.469      0.39     -58    32
# Comp:  2             [SII]6731      4.501      0.39     -58    32
# Comp:  2              HeII4687      0.000      0.39     -58    32
# Comp:  2               HeI5876     0.1983      0.39     -58    32
# Comp:  2          [OIII]5007_d      10.95      0.50     -58    32
# Comp:  2            [OI]6300_d      2.781      0.50     -58    32
# Comp:  2           [NII]6583_d      6.360      0.50     -58    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        74
#  comp.  1:       -62        34
#  comp.  2:       -55        20
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.551      0.40     -62    34
# Comp:  1                Halpha      21.55      0.40     -62    34
# Comp:  2             [SII]6716      7.108      0.38     -55    20
# Comp:  2             [SII]6731      4.047      0.38     -55    20
# Comp:  2              HeII4687     0.1124      0.38     -55    20
# Comp:  2               HeI5876    0.07519      0.38     -55    20
# Comp:  2          [OIII]5007_d      10.45      0.48     -55    20
# Comp:  2            [OI]6300_d      2.720      0.48     -55    20
# Comp:  2           [NII]6583_d      6.363      0.48     -55    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        56
#  comp.  1:       -63        32
#  comp.  2:       -55        48
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.672      0.39     -63    32
# Comp:  1                Halpha      21.07      0.39     -63    32
# Comp:  2             [SII]6716      7.707      0.42     -55    48
# Comp:  2             [SII]6731      4.559      0.42     -55    48
# Comp:  2              HeII4687      0.000      0.42     -55    48
# Comp:  2               HeI5876    0.08423      0.42     -55    48
# Comp:  2          [OIII]5007_d      9.999      0.52     -55    48
# Comp:  2            [OI]6300_d      3.760      0.52     -55    48
# Comp:  2           [NII]6583_d      7.103      0.52     -55    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:       -62        41
#  comp.  2:       -55        42
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.471      0.40     -62    41
# Comp:  1                Halpha      21.64      0.40     -62    41
# Comp:  2             [SII]6716      7.937      0.41     -55    42
# Comp:  2             [SII]6731      4.729      0.41     -55    42
# Comp:  2              HeII4687     0.3036      0.41     -55    42
# Comp:  2               HeI5876     0.2963      0.41     -55    42
# Comp:  2          [OIII]5007_d      10.44      0.51     -55    42
# Comp:  2            [OI]6300_d      3.371      0.51     -55    42
# Comp:  2           [NII]6583_d      7.167      0.51     -55    42
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.54547096, 0.53394973, 0.30137372, 0.26747268, 0.14673465,
#        0.11234012, 0.72339732, 0.48081616, 0.39124574])

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 7.89093597, 29.0445461 , 10.61489086,  6.20979943,  0.        ,
#         0.26426548, 11.39118458,  3.93123517,  9.31384694])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_19_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_19", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_19_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_19_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_19_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.166814    0.011531
# 1        Halpha  0.614001    0.011288
# 2     [SII]6716  0.224399    0.006371
# 3     [SII]6731  0.131275    0.005654
# 4      HeII4687  0.000000    0.003102
# 5       HeI5876  0.005587    0.002375
# 6  [OIII]5007_d  0.240809    0.015293
# 7    [OI]6300_d  0.083106    0.010164
# 8   [NII]6583_d  0.196895    0.008271
#           Name      Flux  Error_flux
# 0        Hbeta  0.166814    0.011531
# 1       Halpha  0.614001    0.011288
# 2    [SII]6716  0.224399    0.006371
# 3    [SII]6731  0.131275    0.005654
# 4     HeII4687  0.000000    0.003102
# 5      HeI5876  0.005587    0.002375
# 6   [OIII]4959  0.060202    0.015293
# 7   [OIII]5007  0.180607    0.015293
# 8     [OI]6300  0.062330    0.010164
# 9     [OI]6364  0.020777    0.010164
# 10   [NII]6548  0.049224    0.008271
# 11   [NII]6583  0.147671    0.008271

# %%
np.median(flux_rf_rebin)
# Out:
# 0.021139985353497596
