# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_15.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_15']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.08619983 0.06497642 0.0802474  ... 0.05297466 0.04909692 0.05272235] [0.0061128 0.0061128 0.0061128 ... 0.0061128 0.0061128 0.0061128]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        64
# chi2/DOF: 0.006287; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        61
# chi2/DOF: 0.005090; DOF: 1925; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-56.1179481 ,  61.12972352])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        70
#  comp.  1:       -68        31
#  comp.  2:       -70        35
# chi2/DOF: 0.8184; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.00      0.19     -68    31
# Comp:  1                Halpha      39.72      0.19     -68    31
# Comp:  2             [SII]6716      7.973      0.19     -70    35
# Comp:  2             [SII]6731      5.679      0.19     -70    35
# Comp:  2              HeII4687    0.03368      0.19     -70    35
# Comp:  2               HeI5876      1.323      0.19     -70    35
# Comp:  2          [OIII]5007_d      11.66      0.24     -70    35
# Comp:  2            [OI]6300_d      1.224      0.24     -70    35
# Comp:  2           [NII]6583_d      10.97      0.24     -70    35
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  47.06; gas flux:     11 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  174.5; gas flux:     54 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   34.9; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  23.77; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.1512; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  5.957; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  39.39; gas flux:     12 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.953; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  35.11; gas flux:     15 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       108
#  comp.  1:       -69        35
#  comp.  2:       -73        28
# chi2/DOF: 0.7908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.70      0.19     -69    35
# Comp:  1                Halpha      40.35      0.19     -69    35
# Comp:  2             [SII]6716      7.806      0.18     -73    28
# Comp:  2             [SII]6731      5.786      0.18     -73    28
# Comp:  2              HeII4687      0.000      0.18     -73    28
# Comp:  2               HeI5876      1.166      0.18     -73    28
# Comp:  2          [OIII]5007_d      11.53      0.23     -73    28
# Comp:  2            [OI]6300_d      1.069      0.23     -73    28
# Comp:  2           [NII]6583_d      10.55      0.23     -73    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        79
#  comp.  1:       -67        33
#  comp.  2:       -71        28
# chi2/DOF: 0.7940; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.99      0.19     -67    33
# Comp:  1                Halpha      39.85      0.19     -67    33
# Comp:  2             [SII]6716      7.756      0.18     -71    28
# Comp:  2             [SII]6731      5.354      0.18     -71    28
# Comp:  2              HeII4687      0.000      0.18     -71    28
# Comp:  2               HeI5876      1.499      0.18     -71    28
# Comp:  2          [OIII]5007_d      11.01      0.23     -71    28
# Comp:  2            [OI]6300_d      1.236      0.23     -71    28
# Comp:  2           [NII]6583_d      10.86      0.23     -71    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        82
#  comp.  1:       -69        30
#  comp.  2:       -66        39
# chi2/DOF: 0.7952; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.04      0.19     -69    30
# Comp:  1                Halpha      40.01      0.19     -69    30
# Comp:  2             [SII]6716      7.719      0.19     -66    39
# Comp:  2             [SII]6731      6.055      0.19     -66    39
# Comp:  2              HeII4687      0.000      0.19     -66    39
# Comp:  2               HeI5876      1.158      0.19     -66    39
# Comp:  2          [OIII]5007_d      11.75      0.24     -66    39
# Comp:  2            [OI]6300_d      1.316      0.24     -66    39
# Comp:  2           [NII]6583_d      10.88      0.24     -66    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        95
#  comp.  1:       -68        27
#  comp.  2:       -71        30
# chi2/DOF: 0.7841; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.474      0.18     -68    27
# Comp:  1                Halpha      38.95      0.18     -68    27
# Comp:  2             [SII]6716      7.761      0.19     -71    30
# Comp:  2             [SII]6731      5.690      0.19     -71    30
# Comp:  2              HeII4687     0.1126      0.19     -71    30
# Comp:  2               HeI5876      1.313      0.19     -71    30
# Comp:  2          [OIII]5007_d      11.67      0.23     -71    30
# Comp:  2            [OI]6300_d      1.119      0.23     -71    30
# Comp:  2           [NII]6583_d      10.54      0.23     -71    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        68
#  comp.  1:       -69        28
#  comp.  2:       -71        32
# chi2/DOF: 0.7946; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.93      0.19     -69    28
# Comp:  1                Halpha      39.46      0.19     -69    28
# Comp:  2             [SII]6716      8.253      0.19     -71    32
# Comp:  2             [SII]6731      5.362      0.19     -71    32
# Comp:  2              HeII4687    0.05444      0.19     -71    32
# Comp:  2               HeI5876      1.156      0.19     -71    32
# Comp:  2          [OIII]5007_d      11.65      0.24     -71    32
# Comp:  2            [OI]6300_d      1.202      0.24     -71    32
# Comp:  2           [NII]6583_d      11.09      0.24     -71    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        82
#  comp.  1:       -68        25
#  comp.  2:       -65        44
# chi2/DOF: 0.7787; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.38      0.18     -68    25
# Comp:  1                Halpha      39.22      0.18     -68    25
# Comp:  2             [SII]6716      8.299      0.19     -65    44
# Comp:  2             [SII]6731      5.822      0.19     -65    44
# Comp:  2              HeII4687     0.1145      0.19     -65    44
# Comp:  2               HeI5876      1.479      0.19     -65    44
# Comp:  2          [OIII]5007_d      11.95      0.25     -65    44
# Comp:  2            [OI]6300_d      1.367      0.25     -65    44
# Comp:  2           [NII]6583_d      11.60      0.25     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        93
#  comp.  1:       -67        31
#  comp.  2:       -73        32
# chi2/DOF: 0.8033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.11      0.19     -67    31
# Comp:  1                Halpha      39.59      0.19     -67    31
# Comp:  2             [SII]6716      7.498      0.19     -73    32
# Comp:  2             [SII]6731      5.945      0.19     -73    32
# Comp:  2              HeII4687     0.1191      0.19     -73    32
# Comp:  2               HeI5876      1.262      0.19     -73    32
# Comp:  2          [OIII]5007_d      11.83      0.24     -73    32
# Comp:  2            [OI]6300_d      1.218      0.24     -73    32
# Comp:  2           [NII]6583_d      10.77      0.24     -73    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        60
#  comp.  1:       -68        29
#  comp.  2:       -66        44
# chi2/DOF: 0.7743; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.57      0.19     -68    29
# Comp:  1                Halpha      39.29      0.19     -68    29
# Comp:  2             [SII]6716      8.214      0.19     -66    44
# Comp:  2             [SII]6731      5.982      0.19     -66    44
# Comp:  2              HeII4687      0.000      0.19     -66    44
# Comp:  2               HeI5876      1.405      0.19     -66    44
# Comp:  2          [OIII]5007_d      12.11      0.25     -66    44
# Comp:  2            [OI]6300_d      1.341      0.25     -66    44
# Comp:  2           [NII]6583_d      11.26      0.25     -66    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        81
#  comp.  1:       -68        27
#  comp.  2:       -66        42
# chi2/DOF: 0.7743; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.956      0.18     -68    27
# Comp:  1                Halpha      39.28      0.18     -68    27
# Comp:  2             [SII]6716      8.515      0.19     -66    42
# Comp:  2             [SII]6731      5.752      0.19     -66    42
# Comp:  2              HeII4687     0.1413      0.19     -66    42
# Comp:  2               HeI5876      1.385      0.19     -66    42
# Comp:  2          [OIII]5007_d      12.33      0.24     -66    42
# Comp:  2            [OI]6300_d      1.267      0.24     -66    42
# Comp:  2           [NII]6583_d      11.47      0.24     -66    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        64
#  comp.  1:       -68        34
#  comp.  2:       -72        26
# chi2/DOF: 0.7925; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.61      0.19     -68    34
# Comp:  1                Halpha      40.12      0.19     -68    34
# Comp:  2             [SII]6716      7.770      0.18     -72    26
# Comp:  2             [SII]6731      5.648      0.18     -72    26
# Comp:  2              HeII4687      0.000      0.18     -72    26
# Comp:  2               HeI5876      1.356      0.18     -72    26
# Comp:  2          [OIII]5007_d      10.99      0.23     -72    26
# Comp:  2            [OI]6300_d      1.100      0.23     -72    26
# Comp:  2           [NII]6583_d      10.64      0.23     -72    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        44
#  comp.  1:       -69        28
#  comp.  2:       -68        31
# chi2/DOF: 0.7877; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.29      0.18     -69    28
# Comp:  1                Halpha      39.78      0.18     -69    28
# Comp:  2             [SII]6716      7.776      0.19     -68    31
# Comp:  2             [SII]6731      5.532      0.19     -68    31
# Comp:  2              HeII4687     0.1018      0.19     -68    31
# Comp:  2               HeI5876      1.490      0.19     -68    31
# Comp:  2          [OIII]5007_d      10.90      0.24     -68    31
# Comp:  2            [OI]6300_d      1.317      0.24     -68    31
# Comp:  2           [NII]6583_d      10.99      0.24     -68    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        14
#  comp.  1:       -69        35
#  comp.  2:       -69        34
# chi2/DOF: 0.7820; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.773      0.19     -69    35
# Comp:  1                Halpha      40.46      0.19     -69    35
# Comp:  2             [SII]6716      7.982      0.19     -69    34
# Comp:  2             [SII]6731      5.678      0.19     -69    34
# Comp:  2              HeII4687      0.000      0.19     -69    34
# Comp:  2               HeI5876      1.595      0.19     -69    34
# Comp:  2          [OIII]5007_d      11.32      0.24     -69    34
# Comp:  2            [OI]6300_d      1.220      0.24     -69    34
# Comp:  2           [NII]6583_d      10.84      0.24     -69    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48       100
#  comp.  1:       -70        30
#  comp.  2:       -71        35
# chi2/DOF: 0.7935; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.83      0.19     -70    30
# Comp:  1                Halpha      39.64      0.19     -70    30
# Comp:  2             [SII]6716      8.349      0.19     -71    35
# Comp:  2             [SII]6731      5.944      0.19     -71    35
# Comp:  2              HeII4687      0.000      0.19     -71    35
# Comp:  2               HeI5876      1.382      0.19     -71    35
# Comp:  2          [OIII]5007_d      11.87      0.24     -71    35
# Comp:  2            [OI]6300_d      1.085      0.24     -71    35
# Comp:  2           [NII]6583_d      10.94      0.24     -71    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        66
#  comp.  1:       -67        33
#  comp.  2:       -67        41
# chi2/DOF: 0.7775; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.14      0.19     -67    33
# Comp:  1                Halpha      39.86      0.19     -67    33
# Comp:  2             [SII]6716      8.509      0.19     -67    41
# Comp:  2             [SII]6731      5.777      0.19     -67    41
# Comp:  2              HeII4687    0.03744      0.19     -67    41
# Comp:  2               HeI5876      1.565      0.19     -67    41
# Comp:  2          [OIII]5007_d      12.43      0.24     -67    41
# Comp:  2            [OI]6300_d      1.283      0.24     -67    41
# Comp:  2           [NII]6583_d      11.11      0.24     -67    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        65
#  comp.  1:       -68        25
#  comp.  2:       -71        27
# chi2/DOF: 0.7607; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.582      0.18     -68    25
# Comp:  1                Halpha      39.10      0.18     -68    25
# Comp:  2             [SII]6716      7.783      0.18     -71    27
# Comp:  2             [SII]6731      5.198      0.18     -71    27
# Comp:  2              HeII4687     0.1559      0.18     -71    27
# Comp:  2               HeI5876      1.332      0.18     -71    27
# Comp:  2          [OIII]5007_d      10.97      0.23     -71    27
# Comp:  2            [OI]6300_d      1.273      0.23     -71    27
# Comp:  2           [NII]6583_d      10.54      0.23     -71    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        52
#  comp.  1:       -68        28
#  comp.  2:       -70        40
# chi2/DOF: 0.7979; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.753      0.19     -68    28
# Comp:  1                Halpha      39.34      0.19     -68    28
# Comp:  2             [SII]6716      8.164      0.19     -70    40
# Comp:  2             [SII]6731      5.509      0.19     -70    40
# Comp:  2              HeII4687      0.000      0.19     -70    40
# Comp:  2               HeI5876      1.381      0.19     -70    40
# Comp:  2          [OIII]5007_d      11.82      0.24     -70    40
# Comp:  2            [OI]6300_d      1.221      0.24     -70    40
# Comp:  2           [NII]6583_d      11.25      0.24     -70    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        63
#  comp.  1:       -69        28
#  comp.  2:       -69        29
# chi2/DOF: 0.7916; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.01      0.18     -69    28
# Comp:  1                Halpha      39.41      0.18     -69    28
# Comp:  2             [SII]6716      8.154      0.19     -69    29
# Comp:  2             [SII]6731      5.633      0.19     -69    29
# Comp:  2              HeII4687     0.1471      0.19     -69    29
# Comp:  2               HeI5876      1.351      0.19     -69    29
# Comp:  2          [OIII]5007_d      10.99      0.23     -69    29
# Comp:  2            [OI]6300_d      1.312      0.23     -69    29
# Comp:  2           [NII]6583_d      11.01      0.23     -69    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        52
#  comp.  1:       -68        34
#  comp.  2:       -70        35
# chi2/DOF: 0.7804; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.751      0.19     -68    34
# Comp:  1                Halpha      40.35      0.19     -68    34
# Comp:  2             [SII]6716      8.001      0.19     -70    35
# Comp:  2             [SII]6731      5.276      0.19     -70    35
# Comp:  2              HeII4687      0.000      0.19     -70    35
# Comp:  2               HeI5876      1.402      0.19     -70    35
# Comp:  2          [OIII]5007_d      11.55      0.24     -70    35
# Comp:  2            [OI]6300_d      1.152      0.24     -70    35
# Comp:  2           [NII]6583_d      10.98      0.24     -70    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        83
#  comp.  1:       -69        31
#  comp.  2:       -67        30
# chi2/DOF: 0.7772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.652      0.19     -69    31
# Comp:  1                Halpha      39.87      0.19     -69    31
# Comp:  2             [SII]6716      8.108      0.19     -67    30
# Comp:  2             [SII]6731      5.521      0.19     -67    30
# Comp:  2              HeII4687      0.000      0.19     -67    30
# Comp:  2               HeI5876      1.252      0.19     -67    30
# Comp:  2          [OIII]5007_d      10.80      0.24     -67    30
# Comp:  2            [OI]6300_d      1.265      0.24     -67    30
# Comp:  2           [NII]6583_d      10.58      0.24     -67    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        53
#  comp.  1:       -69        31
#  comp.  2:       -71        39
# chi2/DOF: 0.7800; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.639      0.19     -69    31
# Comp:  1                Halpha      39.82      0.19     -69    31
# Comp:  2             [SII]6716      7.810      0.19     -71    39
# Comp:  2             [SII]6731      6.135      0.19     -71    39
# Comp:  2              HeII4687    0.02072      0.19     -71    39
# Comp:  2               HeI5876      1.094      0.19     -71    39
# Comp:  2          [OIII]5007_d      12.43      0.24     -71    39
# Comp:  2            [OI]6300_d      1.220      0.24     -71    39
# Comp:  2           [NII]6583_d      11.39      0.24     -71    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        99
#  comp.  1:       -69        27
#  comp.  2:       -70        42
# chi2/DOF: 0.7850; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.21      0.18     -69    27
# Comp:  1                Halpha      39.19      0.18     -69    27
# Comp:  2             [SII]6716      8.126      0.19     -70    42
# Comp:  2             [SII]6731      6.150      0.19     -70    42
# Comp:  2              HeII4687     0.1034      0.19     -70    42
# Comp:  2               HeI5876      1.576      0.19     -70    42
# Comp:  2          [OIII]5007_d      11.47      0.24     -70    42
# Comp:  2            [OI]6300_d      1.396      0.24     -70    42
# Comp:  2           [NII]6583_d      11.24      0.24     -70    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61       113
#  comp.  1:       -69        28
#  comp.  2:       -74        26
# chi2/DOF: 0.7950; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.03      0.19     -69    28
# Comp:  1                Halpha      39.02      0.19     -69    28
# Comp:  2             [SII]6716      7.701      0.18     -74    26
# Comp:  2             [SII]6731      5.584      0.18     -74    26
# Comp:  2              HeII4687     0.1756      0.18     -74    26
# Comp:  2               HeI5876      1.340      0.18     -74    26
# Comp:  2          [OIII]5007_d      11.46      0.23     -74    26
# Comp:  2            [OI]6300_d      1.089      0.23     -74    26
# Comp:  2           [NII]6583_d      10.76      0.23     -74    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        66
#  comp.  1:       -69        34
#  comp.  2:       -71        38
# chi2/DOF: 0.8029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.80      0.19     -69    34
# Comp:  1                Halpha      40.52      0.19     -69    34
# Comp:  2             [SII]6716      7.977      0.19     -71    38
# Comp:  2             [SII]6731      5.833      0.19     -71    38
# Comp:  2              HeII4687    0.02118      0.19     -71    38
# Comp:  2               HeI5876      1.114      0.19     -71    38
# Comp:  2          [OIII]5007_d      11.68      0.24     -71    38
# Comp:  2            [OI]6300_d     0.9651      0.24     -71    38
# Comp:  2           [NII]6583_d      11.06      0.24     -71    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        92
#  comp.  1:       -70        30
#  comp.  2:       -73        36
# chi2/DOF: 0.7986; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.14      0.19     -70    30
# Comp:  1                Halpha      40.01      0.19     -70    30
# Comp:  2             [SII]6716      8.319      0.19     -73    36
# Comp:  2             [SII]6731      5.830      0.19     -73    36
# Comp:  2              HeII4687     0.1933      0.19     -73    36
# Comp:  2               HeI5876      1.349      0.19     -73    36
# Comp:  2          [OIII]5007_d      11.82      0.24     -73    36
# Comp:  2            [OI]6300_d      1.268      0.24     -73    36
# Comp:  2           [NII]6583_d      10.89      0.24     -73    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        61
#  comp.  1:       -67        34
#  comp.  2:       -69        41
# chi2/DOF: 0.7949; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.52      0.19     -67    34
# Comp:  1                Halpha      39.87      0.19     -67    34
# Comp:  2             [SII]6716      8.461      0.19     -69    41
# Comp:  2             [SII]6731      5.618      0.19     -69    41
# Comp:  2              HeII4687    0.05399      0.19     -69    41
# Comp:  2               HeI5876      1.192      0.19     -69    41
# Comp:  2          [OIII]5007_d      12.50      0.24     -69    41
# Comp:  2            [OI]6300_d      1.292      0.24     -69    41
# Comp:  2           [NII]6583_d      11.48      0.24     -69    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        47
#  comp.  1:       -68        25
#  comp.  2:       -72        36
# chi2/DOF: 0.7975; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.30      0.18     -68    25
# Comp:  1                Halpha      39.07      0.18     -68    25
# Comp:  2             [SII]6716      7.698      0.19     -72    36
# Comp:  2             [SII]6731      5.814      0.19     -72    36
# Comp:  2              HeII4687      0.000      0.19     -72    36
# Comp:  2               HeI5876      1.480      0.19     -72    36
# Comp:  2          [OIII]5007_d      12.06      0.24     -72    36
# Comp:  2            [OI]6300_d      1.213      0.24     -72    36
# Comp:  2           [NII]6583_d      10.87      0.24     -72    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        78
#  comp.  1:       -71        30
#  comp.  2:       -72        37
# chi2/DOF: 0.7873; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.66      0.19     -71    30
# Comp:  1                Halpha      40.08      0.19     -71    30
# Comp:  2             [SII]6716      7.996      0.19     -72    37
# Comp:  2             [SII]6731      5.366      0.19     -72    37
# Comp:  2              HeII4687      0.000      0.19     -72    37
# Comp:  2               HeI5876      1.370      0.19     -72    37
# Comp:  2          [OIII]5007_d      12.30      0.24     -72    37
# Comp:  2            [OI]6300_d      1.164      0.24     -72    37
# Comp:  2           [NII]6583_d      11.06      0.24     -72    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       102
#  comp.  1:       -70        28
#  comp.  2:       -70        40
# chi2/DOF: 0.7913; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.69      0.19     -70    28
# Comp:  1                Halpha      39.74      0.19     -70    28
# Comp:  2             [SII]6716      8.132      0.19     -70    40
# Comp:  2             [SII]6731      5.998      0.19     -70    40
# Comp:  2              HeII4687      0.000      0.19     -70    40
# Comp:  2               HeI5876      1.134      0.19     -70    40
# Comp:  2          [OIII]5007_d      11.45      0.24     -70    40
# Comp:  2            [OI]6300_d      1.293      0.24     -70    40
# Comp:  2           [NII]6583_d      11.25      0.24     -70    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87       100
#  comp.  1:       -70        31
#  comp.  2:       -65        41
# chi2/DOF: 0.7766; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.438      0.19     -70    31
# Comp:  1                Halpha      39.93      0.19     -70    31
# Comp:  2             [SII]6716      8.161      0.19     -65    41
# Comp:  2             [SII]6731      5.840      0.19     -65    41
# Comp:  2              HeII4687     0.1477      0.19     -65    41
# Comp:  2               HeI5876      1.370      0.19     -65    41
# Comp:  2          [OIII]5007_d      12.37      0.24     -65    41
# Comp:  2            [OI]6300_d      1.273      0.24     -65    41
# Comp:  2           [NII]6583_d      11.26      0.24     -65    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        83
#  comp.  1:       -68        25
#  comp.  2:       -74        24
# chi2/DOF: 0.7726; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.17      0.18     -68    25
# Comp:  1                Halpha      39.26      0.18     -68    25
# Comp:  2             [SII]6716      7.716      0.18     -74    24
# Comp:  2             [SII]6731      5.667      0.18     -74    24
# Comp:  2              HeII4687      0.000      0.18     -74    24
# Comp:  2               HeI5876      1.372      0.18     -74    24
# Comp:  2          [OIII]5007_d      11.25      0.23     -74    24
# Comp:  2            [OI]6300_d      1.008      0.23     -74    24
# Comp:  2           [NII]6583_d      10.85      0.23     -74    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        32
#  comp.  1:       -67        33
#  comp.  2:       -69        40
# chi2/DOF: 0.7983; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.91      0.19     -67    33
# Comp:  1                Halpha      39.81      0.19     -67    33
# Comp:  2             [SII]6716      8.120      0.19     -69    40
# Comp:  2             [SII]6731      6.099      0.19     -69    40
# Comp:  2              HeII4687      0.000      0.19     -69    40
# Comp:  2               HeI5876      1.288      0.19     -69    40
# Comp:  2          [OIII]5007_d      11.93      0.24     -69    40
# Comp:  2            [OI]6300_d      1.140      0.24     -69    40
# Comp:  2           [NII]6583_d      11.14      0.24     -69    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        74
#  comp.  1:       -68        29
#  comp.  2:       -67        40
# chi2/DOF: 0.7791; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.25      0.19     -68    29
# Comp:  1                Halpha      39.43      0.19     -68    29
# Comp:  2             [SII]6716      8.453      0.19     -67    40
# Comp:  2             [SII]6731      5.984      0.19     -67    40
# Comp:  2              HeII4687      0.000      0.19     -67    40
# Comp:  2               HeI5876      1.308      0.19     -67    40
# Comp:  2          [OIII]5007_d      12.22      0.24     -67    40
# Comp:  2            [OI]6300_d      1.206      0.24     -67    40
# Comp:  2           [NII]6583_d      10.94      0.24     -67    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110        97
#  comp.  1:       -68        26
#  comp.  2:       -68        39
# chi2/DOF: 0.7843; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.84      0.18     -68    26
# Comp:  1                Halpha      38.85      0.18     -68    26
# Comp:  2             [SII]6716      8.496      0.19     -68    39
# Comp:  2             [SII]6731      5.340      0.19     -68    39
# Comp:  2              HeII4687     0.1107      0.19     -68    39
# Comp:  2               HeI5876      1.353      0.19     -68    39
# Comp:  2          [OIII]5007_d      12.07      0.24     -68    39
# Comp:  2            [OI]6300_d      1.237      0.24     -68    39
# Comp:  2           [NII]6583_d      11.32      0.24     -68    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        60
#  comp.  1:       -67        27
#  comp.  2:       -67        35
# chi2/DOF: 0.8017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.42      0.18     -67    27
# Comp:  1                Halpha      39.24      0.18     -67    27
# Comp:  2             [SII]6716      8.241      0.19     -67    35
# Comp:  2             [SII]6731      5.641      0.19     -67    35
# Comp:  2              HeII4687      0.000      0.19     -67    35
# Comp:  2               HeI5876      1.339      0.19     -67    35
# Comp:  2          [OIII]5007_d      11.36      0.24     -67    35
# Comp:  2            [OI]6300_d      1.105      0.24     -67    35
# Comp:  2           [NII]6583_d      10.76      0.24     -67    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        74
#  comp.  1:       -69        29
#  comp.  2:       -71        24
# chi2/DOF: 0.7993; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.16      0.19     -69    29
# Comp:  1                Halpha      39.65      0.19     -69    29
# Comp:  2             [SII]6716      7.693      0.18     -71    24
# Comp:  2             [SII]6731      5.238      0.18     -71    24
# Comp:  2              HeII4687     0.3153      0.18     -71    24
# Comp:  2               HeI5876      1.487      0.18     -71    24
# Comp:  2          [OIII]5007_d      10.80      0.23     -71    24
# Comp:  2            [OI]6300_d      1.190      0.23     -71    24
# Comp:  2           [NII]6583_d      10.47      0.23     -71    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        64
#  comp.  1:       -67        32
#  comp.  2:       -69        33
# chi2/DOF: 0.7994; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.19      0.19     -67    32
# Comp:  1                Halpha      39.79      0.19     -67    32
# Comp:  2             [SII]6716      8.179      0.19     -69    33
# Comp:  2             [SII]6731      6.023      0.19     -69    33
# Comp:  2              HeII4687      0.000      0.19     -69    33
# Comp:  2               HeI5876      1.328      0.19     -69    33
# Comp:  2          [OIII]5007_d      11.54      0.24     -69    33
# Comp:  2            [OI]6300_d      1.235      0.24     -69    33
# Comp:  2           [NII]6583_d      11.16      0.24     -69    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        77
#  comp.  1:       -69        33
#  comp.  2:       -68        31
# chi2/DOF: 0.7805; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.71      0.19     -69    33
# Comp:  1                Halpha      40.40      0.19     -69    33
# Comp:  2             [SII]6716      7.526      0.19     -68    31
# Comp:  2             [SII]6731      5.251      0.19     -68    31
# Comp:  2              HeII4687      0.000      0.19     -68    31
# Comp:  2               HeI5876      1.058      0.19     -68    31
# Comp:  2          [OIII]5007_d      11.19      0.24     -68    31
# Comp:  2            [OI]6300_d      1.185      0.24     -68    31
# Comp:  2           [NII]6583_d      10.86      0.24     -68    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        46
#  comp.  1:       -68        28
#  comp.  2:       -72        37
# chi2/DOF: 0.7874; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.970      0.19     -68    28
# Comp:  1                Halpha      39.16      0.19     -68    28
# Comp:  2             [SII]6716      8.065      0.19     -72    37
# Comp:  2             [SII]6731      5.589      0.19     -72    37
# Comp:  2              HeII4687     0.1137      0.19     -72    37
# Comp:  2               HeI5876      1.338      0.19     -72    37
# Comp:  2          [OIII]5007_d      12.36      0.24     -72    37
# Comp:  2            [OI]6300_d      1.290      0.24     -72    37
# Comp:  2           [NII]6583_d      11.23      0.24     -72    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        52
#  comp.  1:       -68        26
#  comp.  2:       -68        32
# chi2/DOF: 0.7972; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.04      0.18     -68    26
# Comp:  1                Halpha      38.99      0.18     -68    26
# Comp:  2             [SII]6716      7.826      0.19     -68    32
# Comp:  2             [SII]6731      5.440      0.19     -68    32
# Comp:  2              HeII4687      0.000      0.19     -68    32
# Comp:  2               HeI5876      1.314      0.19     -68    32
# Comp:  2          [OIII]5007_d      11.34      0.24     -68    32
# Comp:  2            [OI]6300_d      1.183      0.24     -68    32
# Comp:  2           [NII]6583_d      10.94      0.24     -68    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        50
#  comp.  1:       -67        32
#  comp.  2:       -71        38
# chi2/DOF: 0.7916; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.66      0.19     -67    32
# Comp:  1                Halpha      39.58      0.19     -67    32
# Comp:  2             [SII]6716      8.058      0.19     -71    38
# Comp:  2             [SII]6731      5.510      0.19     -71    38
# Comp:  2              HeII4687      0.000      0.19     -71    38
# Comp:  2               HeI5876      1.472      0.19     -71    38
# Comp:  2          [OIII]5007_d      12.35      0.24     -71    38
# Comp:  2            [OI]6300_d      1.096      0.24     -71    38
# Comp:  2           [NII]6583_d      11.22      0.24     -71    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        66
#  comp.  1:       -69        35
#  comp.  2:       -65        40
# chi2/DOF: 0.7674; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.620      0.19     -69    35
# Comp:  1                Halpha      40.60      0.19     -69    35
# Comp:  2             [SII]6716      8.067      0.19     -65    40
# Comp:  2             [SII]6731      5.610      0.19     -65    40
# Comp:  2              HeII4687      0.000      0.19     -65    40
# Comp:  2               HeI5876      1.535      0.19     -65    40
# Comp:  2          [OIII]5007_d      11.68      0.24     -65    40
# Comp:  2            [OI]6300_d      1.154      0.24     -65    40
# Comp:  2           [NII]6583_d      10.95      0.24     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43       101
#  comp.  1:       -70        30
#  comp.  2:       -69        41
# chi2/DOF: 0.7792; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.47      0.19     -70    30
# Comp:  1                Halpha      40.30      0.19     -70    30
# Comp:  2             [SII]6716      7.810      0.19     -69    41
# Comp:  2             [SII]6731      5.800      0.19     -69    41
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.751      0.19     -67    31
# Comp:  1                Halpha      39.42      0.19     -67    31
# Comp:  2             [SII]6716      7.337      0.18     -70    27
# Comp:  2             [SII]6731      5.509      0.18     -70    27
# Comp:  2              HeII4687     0.1525      0.18     -70    27
# Comp:  2               HeI5876      1.344      0.18     -70    27
# Comp:  2          [OIII]5007_d      11.22      0.23     -70    27
# Comp:  2            [OI]6300_d      1.128      0.23     -70    27
# Comp:  2           [NII]6583_d      10.62      0.23     -70    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        65
#  comp.  1:       -68        36
#  comp.  2:       -64        39
# chi2/DOF: 0.7904; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.31      0.19     -68    36
# Comp:  1                Halpha      40.81      0.19     -68    36
# Comp:  2             [SII]6716      8.032      0.19     -64    39
# Comp:  2             [SII]6731      5.646      0.19     -64    39
# Comp:  2              HeII4687     0.3932      0.19     -64    39
# Comp:  2               HeI5876      1.280      0.19     -64    39
# Comp:  2          [OIII]5007_d      11.41      0.24     -64    39
# Comp:  2            [OI]6300_d      1.191      0.24     -64    39
# Comp:  2           [NII]6583_d      11.26      0.24     -64    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        62
#  comp.  1:       -69        31
#  comp.  2:       -69        39
# chi2/DOF: 0.8062; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.65      0.19     -69    31
# Comp:  1                Halpha      39.93      0.19     -69    31
# Comp:  2             [SII]6716      7.713      0.19     -69    39
# Comp:  2             [SII]6731      5.847      0.19     -69    39
# Comp:  2              HeII4687     0.1248      0.19     -69    39
# Comp:  2               HeI5876      1.572      0.19     -69    39
# Comp:  2          [OIII]5007_d      11.79      0.24     -69    39
# Comp:  2            [OI]6300_d      1.092      0.24     -69    39
# Comp:  2           [NII]6583_d      11.22      0.24     -69    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        66
#  comp.  1:       -69        30
#  comp.  2:       -72        24
# chi2/DOF: 0.8006; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.28      0.19     -69    30
# Comp:  1                Halpha      39.78      0.19     -69    30
# Comp:  2             [SII]6716      7.747      0.18     -72    24
# Comp:  2             [SII]6731      5.776      0.18     -72    24
# Comp:  2              HeII4687      0.000      0.18     -72    24
# Comp:  2               HeI5876      1.330      0.18     -72    24
# Comp:  2          [OIII]5007_d      11.48      0.23     -72    24
# Comp:  2            [OI]6300_d      1.157      0.23     -72    24
# Comp:  2           [NII]6583_d      10.57      0.23     -72    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        73
#  comp.  1:       -70        28
#  comp.  2:       -68        32
# chi2/DOF: 0.7848; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.22      0.18     -70    28
# Comp:  1                Halpha      39.86      0.18     -70    28
# Comp:  2             [SII]6716      7.751      0.19     -68    32
# Comp:  2             [SII]6731      5.918      0.19     -68    32
# Comp:  2              HeII4687      0.000      0.19     -68    32
# Comp:  2               HeI5876      1.117      0.19     -68    32
# Comp:  2          [OIII]5007_d      11.20      0.24     -68    32
# Comp:  2            [OI]6300_d      1.167      0.24     -68    32
# Comp:  2           [NII]6583_d      10.86      0.24     -68    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        71
#  comp.  1:       -69        27
#  comp.  2:       -70        25
# chi2/DOF: 0.7769; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.35      0.18     -69    27
# Comp:  1                Halpha      39.49      0.18     -69    27
# Comp:  2             [SII]6716      7.366      0.18     -70    25
# Comp:  2             [SII]6731      5.761      0.18     -70    25
# Comp:  2              HeII4687      0.000      0.18     -70    25
# Comp:  2               HeI5876      1.306      0.18     -70    25
# Comp:  2          [OIII]5007_d      11.00      0.23     -70    25
# Comp:  2            [OI]6300_d      1.179      0.23     -70    25
# Comp:  2           [NII]6583_d      10.93      0.23     -70    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        75
#  comp.  1:       -68        28
#  comp.  2:       -69        33
# chi2/DOF: 0.8086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.83      0.18     -68    28
# Comp:  1                Halpha      39.09      0.18     -68    28
# Comp:  2             [SII]6716      7.623      0.19     -69    33
# Comp:  2             [SII]6731      5.758      0.19     -69    33
# Comp:  2              HeII4687     0.1441      0.19     -69    33
# Comp:  2               HeI5876      1.233      0.19     -69    33
# Comp:  2          [OIII]5007_d      11.28      0.24     -69    33
# Comp:  2            [OI]6300_d      1.184      0.24     -69    33
# Comp:  2           [NII]6583_d      10.84      0.24     -69    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        98
#  comp.  1:       -69        33
#  comp.  2:       -72        29
# chi2/DOF: 0.7980; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.32      0.19     -69    33
# Comp:  1                Halpha      40.52      0.19     -69    33
# Comp:  2             [SII]6716      7.715      0.19     -72    29
# Comp:  2             [SII]6731      5.498      0.19     -72    29
# Comp:  2              HeII4687    0.09600      0.19     -72    29
# Comp:  2               HeI5876      1.560      0.19     -72    29
# Comp:  2          [OIII]5007_d      11.80      0.23     -72    29
# Comp:  2            [OI]6300_d      1.222      0.23     -72    29
# Comp:  2           [NII]6583_d      10.86      0.23     -72    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        41
#  comp.  1:       -70        31
#  comp.  2:       -66        45
# chi2/DOF: 0.7747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.99      0.19     -70    31
# Comp:  1                Halpha      39.84      0.19     -70    31
# Comp:  2             [SII]6716      8.317      0.19     -66    45
# Comp:  2             [SII]6731      6.161      0.19     -66    45
# Comp:  2              HeII4687      0.000      0.19     -66    45
# Comp:  2               HeI5876      1.383      0.19     -66    45
# Comp:  2          [OIII]5007_d      12.03      0.25     -66    45
# Comp:  2            [OI]6300_d      1.224      0.25     -66    45
# Comp:  2           [NII]6583_d      11.27      0.25     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        94
#  comp.  1:       -69        35
#  comp.  2:       -68        30
# chi2/DOF: 0.7939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.70      0.19     -69    35
# Comp:  1                Halpha      40.44      0.19     -69    35
# Comp:  2             [SII]6716      8.161      0.19     -68    30
# Comp:  2             [SII]6731      5.694      0.19     -68    30
# Comp:  2              HeII4687     0.2772      0.19     -68    30
# Comp:  2               HeI5876      1.016      0.19     -68    30
# Comp:  2          [OIII]5007_d      10.97      0.23     -68    30
# Comp:  2            [OI]6300_d      1.173      0.23     -68    30
# Comp:  2           [NII]6583_d      10.53      0.23     -68    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        34
#  comp.  1:       -68        30
#  comp.  2:       -72        29
# chi2/DOF: 0.8017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.69      0.19     -68    30
# Comp:  1                Halpha      39.26      0.19     -68    30
# Comp:  2             [SII]6716      7.828      0.19     -72    29
# Comp:  2             [SII]6731      5.785      0.19     -72    29
# Comp:  2              HeII4687    0.08382      0.19     -72    29
# Comp:  2               HeI5876      1.014      0.19     -72    29
# Comp:  2          [OIII]5007_d      11.60      0.23     -72    29
# Comp:  2            [OI]6300_d      1.112      0.23     -72    29
# Comp:  2           [NII]6583_d      10.80      0.23     -72    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        74
#  comp.  1:       -68        26
#  comp.  2:       -68        33
# chi2/DOF: 0.7711; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.42      0.18     -68    26
# Comp:  1                Halpha      39.21      0.18     -68    26
# Comp:  2             [SII]6716      7.893      0.19     -68    33
# Comp:  2             [SII]6731      5.477      0.19     -68    33
# Comp:  2              HeII4687      0.000      0.19     -68    33
# Comp:  2               HeI5876      1.047      0.19     -68    33
# Comp:  2          [OIII]5007_d      11.00      0.24     -68    33
# Comp:  2            [OI]6300_d      1.306      0.24     -68    33
# Comp:  2           [NII]6583_d      11.02      0.24     -68    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        99
#  comp.  1:       -68        29
#  comp.  2:       -69        34
# chi2/DOF: 0.7978; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.37      0.19     -68    29
# Comp:  1                Halpha      39.33      0.19     -68    29
# Comp:  2             [SII]6716      7.962      0.19     -69    34
# Comp:  2             [SII]6731      5.432      0.19     -69    34
# Comp:  2              HeII4687     0.1435      0.19     -69    34
# Comp:  2               HeI5876      1.000      0.19     -69    34
# Comp:  2          [OIII]5007_d      11.29      0.24     -69    34
# Comp:  2            [OI]6300_d      1.269      0.24     -69    34
# Comp:  2           [NII]6583_d      10.72      0.24     -69    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        78
#  comp.  1:       -69        35
#  comp.  2:       -72        36
# chi2/DOF: 0.7918; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.20      0.19     -69    35
# Comp:  1                Halpha      40.35      0.19     -69    35
# Comp:  2             [SII]6716      8.299      0.19     -72    36
# Comp:  2             [SII]6731      5.954      0.19     -72    36
# Comp:  2              HeII4687      0.000      0.19     -72    36
# Comp:  2               HeI5876      1.324      0.19     -72    36
# Comp:  2          [OIII]5007_d      11.98      0.24     -72    36
# Comp:  2            [OI]6300_d      1.182      0.24     -72    36
# Comp:  2           [NII]6583_d      10.94      0.24     -72    36
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.9389744 , 0.70360859, 0.42216893, 0.35856746, 0.10337193,
#        0.19965762, 0.52206203, 0.12211637, 0.34595135])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.11526799e+01, 5.43762881e+01, 1.11688947e+01, 7.97303976e+00,
#        3.29206276e-02, 1.62144831e+00, 1.21714979e+01, 1.60783077e+00,
#        1.50659655e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_15_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_15", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_15_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_15_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_15_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.744390    0.062672
# 1        Halpha  3.629364    0.046963
# 2     [SII]6716  0.745472    0.028178
# 3     [SII]6731  0.532163    0.023933
# 4      HeII4687  0.002197    0.006900
# 5       HeI5876  0.108224    0.013326
# 6  [OIII]5007_d  0.812391    0.034845
# 7    [OI]6300_d  0.107315    0.008151
# 8   [NII]6583_d  1.005583    0.023091
#           Name      Flux  Error_flux
# 0        Hbeta  0.744390    0.062672
# 1       Halpha  3.629364    0.046963
# 2    [SII]6716  0.745472    0.028178
# 3    [SII]6731  0.532163    0.023933
# 4     HeII4687  0.002197    0.006900
# 5      HeI5876  0.108224    0.013326
# 6   [OIII]4959  0.203098    0.034845
# 7   [OIII]5007  0.609293    0.034845
# 8     [OI]6300  0.080486    0.008151
# 9     [OI]6364  0.026829    0.008151
# 10   [NII]6548  0.251396    0.023091
# 11   [NII]6583  0.754187    0.023091

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06674535174289878
