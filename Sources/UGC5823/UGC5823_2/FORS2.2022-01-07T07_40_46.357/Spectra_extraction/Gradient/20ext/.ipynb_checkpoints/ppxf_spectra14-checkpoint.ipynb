# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_14.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_14']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.06443088 0.04987063 0.05189694 ... 0.04750466 0.05146818 0.05297904] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        13
# chi2/DOF: 0.009636; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        38
# chi2/DOF: 0.006673; DOF: 1911; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        12
#  comp.  1:       -80        30
#  comp.  2:       -82        10
# chi2/DOF: 0.9408; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.071      0.20     -80    30
# Comp:  1                Halpha      22.81      0.20     -80    30
# Comp:  2             [SII]6716      5.201      0.19     -82    10
# Comp:  2             [SII]6731      4.227      0.19     -82    10
# Comp:  2              HeII4687     0.6126      0.19     -82    10
# Comp:  2               HeI5876     0.6980      0.19     -82    10
# Comp:  2          [OIII]5007_d      3.865      0.24     -82    10
# Comp:  2            [OI]6300_d     0.8277      0.24     -82    10
# Comp:  2           [NII]6583_d      7.725      0.24     -82    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -78        29
#  comp.  2:       -79        19
# chi2/DOF: 0.9365; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.612      0.20     -78    29
# Comp:  1                Halpha      22.30      0.20     -78    29
# Comp:  2             [SII]6716      5.372      0.19     -79    19
# Comp:  2             [SII]6731      4.210      0.19     -79    19
# Comp:  2              HeII4687     0.6031      0.19     -79    19
# Comp:  2               HeI5876     0.7765      0.19     -79    19
# Comp:  2          [OIII]5007_d      3.664      0.24     -79    19
# Comp:  2            [OI]6300_d     0.7702      0.24     -79    19
# Comp:  2           [NII]6583_d      7.548      0.24     -79    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        21
#  comp.  1:       -79        32
#  comp.  2:       -79         1
# chi2/DOF: 0.9434; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.251      0.20     -79    32
# Comp:  1                Halpha      22.86      0.20     -79    32
# Comp:  2             [SII]6716      5.235      0.19     -79     1
# Comp:  2             [SII]6731      4.114      0.19     -79     1
# Comp:  2              HeII4687     0.6310      0.19     -79     1
# Comp:  2               HeI5876     0.8011      0.19     -79     1
# Comp:  2          [OIII]5007_d      3.915      0.24     -79     1
# Comp:  2            [OI]6300_d     0.8928      0.24     -79     1
# Comp:  2           [NII]6583_d      7.268      0.24     -79     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        23
#  comp.  1:       -80        28
#  comp.  2:       -82        25
# chi2/DOF: 0.9418; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.793      0.20     -80    28
# Comp:  1                Halpha      22.55      0.20     -80    28
# Comp:  2             [SII]6716      5.348      0.20     -82    25
# Comp:  2             [SII]6731      4.231      0.20     -82    25
# Comp:  2              HeII4687     0.6571      0.20     -82    25
# Comp:  2               HeI5876     0.6766      0.20     -82    25
# Comp:  2          [OIII]5007_d      4.023      0.25     -82    25
# Comp:  2            [OI]6300_d     0.5431      0.25     -82    25
# Comp:  2           [NII]6583_d      8.005      0.25     -82    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -79        26
#  comp.  2:       -82        15
# chi2/DOF: 0.9420; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.372      0.20     -79    26
# Comp:  1                Halpha      22.12      0.20     -79    26
# Comp:  2             [SII]6716      5.391      0.19     -82    15
# Comp:  2             [SII]6731      3.968      0.19     -82    15
# Comp:  2              HeII4687     0.6715      0.19     -82    15
# Comp:  2               HeI5876     0.6076      0.19     -82    15
# Comp:  2          [OIII]5007_d      3.348      0.24     -82    15
# Comp:  2            [OI]6300_d      1.099      0.24     -82    15
# Comp:  2           [NII]6583_d      7.735      0.24     -82    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        34
#  comp.  1:       -79        32
#  comp.  2:       -82        22
# chi2/DOF: 0.9408; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.356      0.20     -79    32
# Comp:  1                Halpha      22.70      0.20     -79    32
# Comp:  2             [SII]6716      5.417      0.20     -82    22
# Comp:  2             [SII]6731      4.207      0.20     -82    22
# Comp:  2              HeII4687     0.6777      0.20     -82    22
# Comp:  2               HeI5876     0.7676      0.20     -82    22
# Comp:  2          [OIII]5007_d      3.783      0.25     -82    22
# Comp:  2            [OI]6300_d     0.6428      0.25     -82    22
# Comp:  2           [NII]6583_d      7.611      0.25     -82    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -78        28
#  comp.  2:       -81        22
# chi2/DOF: 0.9328; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.664      0.20     -78    28
# Comp:  1                Halpha      22.53      0.20     -78    28
# Comp:  2             [SII]6716      5.282      0.20     -81    22
# Comp:  2             [SII]6731      4.297      0.20     -81    22
# Comp:  2              HeII4687     0.6371      0.20     -81    22
# Comp:  2               HeI5876     0.7974      0.20     -81    22
# Comp:  2          [OIII]5007_d      4.297      0.25     -81    22
# Comp:  2            [OI]6300_d     0.8809      0.25     -81    22
# Comp:  2           [NII]6583_d      7.773      0.25     -81    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -79        29
#  comp.  2:       -80         7
# chi2/DOF: 0.9454; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.400      0.20     -79    29
# Comp:  1                Halpha      22.53      0.20     -79    29
# Comp:  2             [SII]6716      5.372      0.19     -80     7
# Comp:  2             [SII]6731      4.142      0.19     -80     7
# Comp:  2              HeII4687     0.6680      0.19     -80     7
# Comp:  2               HeI5876     0.7505      0.19     -80     7
# Comp:  2          [OIII]5007_d      3.760      0.24     -80     7
# Comp:  2            [OI]6300_d     0.8165      0.24     -80     7
# Comp:  2           [NII]6583_d      7.337      0.24     -80     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -78        25
#  comp.  2:       -80        14
# chi2/DOF: 0.9312; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.974      0.20     -78    25
# Comp:  1                Halpha      22.40      0.20     -78    25
# Comp:  2             [SII]6716      5.267      0.19     -80    14
# Comp:  2             [SII]6731      4.024      0.19     -80    14
# Comp:  2              HeII4687     0.6640      0.19     -80    14
# Comp:  2               HeI5876     0.8402      0.19     -80    14
# Comp:  2          [OIII]5007_d      3.784      0.24     -80    14
# Comp:  2            [OI]6300_d      1.330      0.24     -80    14
# Comp:  2           [NII]6583_d      7.657      0.24     -80    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        35
#  comp.  1:       -80        33
#  comp.  2:       -82        23
# chi2/DOF: 0.9424; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.651      0.20     -80    33
# Comp:  1                Halpha      22.94      0.20     -80    33
# Comp:  2             [SII]6716      5.444      0.20     -82    23
# Comp:  2             [SII]6731      4.253      0.20     -82    23
# Comp:  2              HeII4687     0.5924      0.20     -82    23
# Comp:  2               HeI5876     0.7640      0.20     -82    23
# Comp:  2          [OIII]5007_d      4.065      0.25     -82    23
# Comp:  2            [OI]6300_d      1.098      0.25     -82    23
# Comp:  2           [NII]6583_d      7.643      0.25     -82    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        52
#  comp.  1:       -78        27
#  comp.  2:       -81         4
# chi2/DOF: 0.9365; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.469      0.20     -78    27
# Comp:  1                Halpha      22.37      0.20     -78    27
# Comp:  2             [SII]6716      5.172      0.19     -81     4
# Comp:  2             [SII]6731      4.199      0.19     -81     4
# Comp:  2              HeII4687     0.7280      0.19     -81     4
# Comp:  2               HeI5876     0.7397      0.19     -81     4
# Comp:  2          [OIII]5007_d      3.377      0.24     -81     4
# Comp:  2            [OI]6300_d     0.9580      0.24     -81     4
# Comp:  2           [NII]6583_d      7.570      0.24     -81     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        32
#  comp.  1:       -80        31
#  comp.  2:       -79         5
# chi2/DOF: 0.9354; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.884      0.20     -80    31
# Comp:  1                Halpha      22.76      0.20     -80    31
# Comp:  2             [SII]6716      5.177      0.19     -79     5
# Comp:  2             [SII]6731      4.086      0.19     -79     5
# Comp:  2              HeII4687     0.6388      0.19     -79     5
# Comp:  2               HeI5876     0.6646      0.19     -79     5
# Comp:  2          [OIII]5007_d      3.878      0.24     -79     5
# Comp:  2            [OI]6300_d      1.204      0.24     -79     5
# Comp:  2           [NII]6583_d      7.394      0.24     -79     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        28
#  comp.  1:       -79        28
#  comp.  2:       -82        10
# chi2/DOF: 0.9393; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.893      0.20     -79    28
# Comp:  1                Halpha      22.28      0.20     -79    28
# Comp:  2             [SII]6716      5.188      0.19     -82    10
# Comp:  2             [SII]6731      4.019      0.19     -82    10
# Comp:  2              HeII4687     0.5754      0.19     -82    10
# Comp:  2               HeI5876     0.6437      0.19     -82    10
# Comp:  2          [OIII]5007_d      3.694      0.24     -82    10
# Comp:  2            [OI]6300_d     0.8622      0.24     -82    10
# Comp:  2           [NII]6583_d      7.694      0.24     -82    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -79        33
#  comp.  2:       -82        21
# chi2/DOF: 0.9354; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.451      0.20     -79    33
# Comp:  1                Halpha      22.87      0.20     -79    33
# Comp:  2             [SII]6716      5.441      0.19     -82    21
# Comp:  2             [SII]6731      4.288      0.19     -82    21
# Comp:  2              HeII4687     0.7242      0.19     -82    21
# Comp:  2               HeI5876     0.8735      0.19     -82    21
# Comp:  2          [OIII]5007_d      4.227      0.25     -82    21
# Comp:  2            [OI]6300_d      1.343      0.25     -82    21
# Comp:  2           [NII]6583_d      7.591      0.25     -82    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        46
#  comp.  1:       -80        30
#  comp.  2:       -82        14
# chi2/DOF: 0.9409; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.758      0.20     -80    30
# Comp:  1                Halpha      22.81      0.20     -80    30
# Comp:  2             [SII]6716      5.248      0.19     -82    14
# Comp:  2             [SII]6731      3.955      0.19     -82    14
# Comp:  2              HeII4687     0.7081      0.19     -82    14
# Comp:  2               HeI5876     0.7677      0.19     -82    14
# Comp:  2          [OIII]5007_d      3.724      0.24     -82    14
# Comp:  2            [OI]6300_d      1.196      0.24     -82    14
# Comp:  2           [NII]6583_d      7.219      0.24     -82    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        25
#  comp.  1:       -78        31
#  comp.  2:       -82        13
# chi2/DOF: 0.9444; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.860      0.20     -78    31
# Comp:  1                Halpha      22.55      0.20     -78    31
# Comp:  2             [SII]6716      5.293      0.19     -82    13
# Comp:  2             [SII]6731      4.017      0.19     -82    13
# Comp:  2              HeII4687     0.5828      0.19     -82    13
# Comp:  2               HeI5876     0.7658      0.19     -82    13
# Comp:  2          [OIII]5007_d      3.952      0.24     -82    13
# Comp:  2            [OI]6300_d     0.9135      0.24     -82    13
# Comp:  2           [NII]6583_d      7.363      0.24     -82    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -81        29
#  comp.  2:       -82        11
# chi2/DOF: 0.9386; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.914      0.20     -81    29
# Comp:  1                Halpha      22.82      0.20     -81    29
# Comp:  2             [SII]6716      5.269      0.19     -82    11
# Comp:  2             [SII]6731      4.208      0.19     -82    11
# Comp:  2              HeII4687     0.7248      0.19     -82    11
# Comp:  2               HeI5876     0.7313      0.19     -82    11
# Comp:  2          [OIII]5007_d      3.717      0.24     -82    11
# Comp:  2            [OI]6300_d     0.8105      0.24     -82    11
# Comp:  2           [NII]6583_d      7.469      0.24     -82    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        39
#  comp.  1:       -79        35
#  comp.  2:       -83         9
# chi2/DOF: 0.9363; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.051      0.20     -79    35
# Comp:  1                Halpha      23.00      0.20     -79    35
# Comp:  2             [SII]6716      5.348      0.19     -83     9
# Comp:  2             [SII]6731      3.897      0.19     -83     9
# Comp:  2              HeII4687     0.6394      0.19     -83     9
# Comp:  2               HeI5876     0.7789      0.19     -83     9
# Comp:  2          [OIII]5007_d      3.840      0.24     -83     9
# Comp:  2            [OI]6300_d      1.164      0.24     -83     9
# Comp:  2           [NII]6583_d      7.703      0.24     -83     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -76        31
#  comp.  2:       -80        15
# chi2/DOF: 0.9426; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.584      0.20     -76    31
# Comp:  1                Halpha      22.53      0.20     -76    31
# Comp:  2             [SII]6716      5.226      0.19     -80    15
# Comp:  2             [SII]6731      4.117      0.19     -80    15
# Comp:  2              HeII4687     0.6678      0.19     -80    15
# Comp:  2               HeI5876     0.7722      0.19     -80    15
# Comp:  2          [OIII]5007_d      4.048      0.24     -80    15
# Comp:  2            [OI]6300_d     0.9374      0.24     -80    15
# Comp:  2           [NII]6583_d      7.459      0.24     -80    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        29
#  comp.  1:       -78        27
#  comp.  2:       -82         1
# chi2/DOF: 0.9389; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.374      0.20     -78    27
# Comp:  1                Halpha      22.10      0.20     -78    27
# Comp:  2             [SII]6716      5.261      0.19     -82     1
# Comp:  2             [SII]6731      4.251      0.19     -82     1
# Comp:  2              HeII4687     0.6555      0.19     -82     1
# Comp:  2               HeI5876     0.6328      0.19     -82     1
# Comp:  2          [OIII]5007_d      3.975      0.24     -82     1
# Comp:  2            [OI]6300_d     0.5259      0.24     -82     1
# Comp:  2           [NII]6583_d      7.354      0.24     -82     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -77        29
#  comp.  2:       -81        19
# chi2/DOF: 0.9347; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.327      0.20     -77    29
# Comp:  1                Halpha      22.41      0.20     -77    29
# Comp:  2             [SII]6716      5.257      0.19     -81    19
# Comp:  2             [SII]6731      4.323      0.19     -81    19
# Comp:  2              HeII4687     0.6369      0.19     -81    19
# Comp:  2               HeI5876     0.7285      0.19     -81    19
# Comp:  2          [OIII]5007_d      3.915      0.24     -81    19
# Comp:  2            [OI]6300_d     0.6496      0.24     -81    19
# Comp:  2           [NII]6583_d      7.643      0.24     -81    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -78        29
#  comp.  2:       -81        18
# chi2/DOF: 0.9376; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.486      0.20     -78    29
# Comp:  1                Halpha      22.60      0.20     -78    29
# Comp:  2             [SII]6716      5.369      0.19     -81    18
# Comp:  2             [SII]6731      4.203      0.19     -81    18
# Comp:  2              HeII4687     0.6569      0.19     -81    18
# Comp:  2               HeI5876     0.8347      0.19     -81    18
# Comp:  2          [OIII]5007_d      4.067      0.24     -81    18
# Comp:  2            [OI]6300_d      1.080      0.24     -81    18
# Comp:  2           [NII]6583_d      7.845      0.24     -81    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        27
#  comp.  1:       -79        30
#  comp.  2:       -79         1
# chi2/DOF: 0.9315; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.702      0.20     -79    30
# Comp:  1                Halpha      22.87      0.20     -79    30
# Comp:  2             [SII]6716      5.168      0.19     -79     1
# Comp:  2             [SII]6731      3.893      0.19     -79     1
# Comp:  2              HeII4687     0.6053      0.19     -79     1
# Comp:  2               HeI5876     0.6037      0.19     -79     1
# Comp:  2          [OIII]5007_d      3.710      0.24     -79     1
# Comp:  2            [OI]6300_d     0.9489      0.24     -79     1
# Comp:  2           [NII]6583_d      7.245      0.24     -79     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -79        31
#  comp.  2:       -83        13
# chi2/DOF: 0.9438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.571      0.20     -79    31
# Comp:  1                Halpha      22.89      0.20     -79    31
# Comp:  2             [SII]6716      5.234      0.19     -83    13
# Comp:  2             [SII]6731      4.168      0.19     -83    13
# Comp:  2              HeII4687     0.7185      0.19     -83    13
# Comp:  2               HeI5876     0.6280      0.19     -83    13
# Comp:  2          [OIII]5007_d      3.467      0.24     -83    13
# Comp:  2            [OI]6300_d      1.128      0.24     -83    13
# Comp:  2           [NII]6583_d      7.597      0.24     -83    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        19
#  comp.  1:       -79        30
#  comp.  2:       -82        19
# chi2/DOF: 0.9389; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.451      0.20     -79    30
# Comp:  1                Halpha      22.85      0.20     -79    30
# Comp:  2             [SII]6716      5.344      0.19     -82    19
# Comp:  2             [SII]6731      4.099      0.19     -82    19
# Comp:  2              HeII4687     0.5676      0.19     -82    19
# Comp:  2               HeI5876     0.8379      0.19     -82    19
# Comp:  2          [OIII]5007_d      3.540      0.24     -82    19
# Comp:  2            [OI]6300_d     0.9814      0.24     -82    19
# Comp:  2           [NII]6583_d      7.548      0.24     -82    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -79        26
#  comp.  2:       -81        19
# chi2/DOF: 0.9337; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.267      0.20     -79    26
# Comp:  1                Halpha      22.30      0.20     -79    26
# Comp:  2             [SII]6716      5.300      0.19     -81    19
# Comp:  2             [SII]6731      4.306      0.19     -81    19
# Comp:  2              HeII4687     0.5735      0.19     -81    19
# Comp:  2               HeI5876     0.7204      0.19     -81    19
# Comp:  2          [OIII]5007_d      3.392      0.25     -81    19
# Comp:  2            [OI]6300_d      1.349      0.25     -81    19
# Comp:  2           [NII]6583_d      7.756      0.25     -81    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        32
#  comp.  1:       -79        32
#  comp.  2:       -82        21
# chi2/DOF: 0.9358; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.448      0.20     -79    32
# Comp:  1                Halpha      22.68      0.20     -79    32
# Comp:  2             [SII]6716      5.479      0.19     -82    21
# Comp:  2             [SII]6731      4.182      0.19     -82    21
# Comp:  2              HeII4687     0.7539      0.19     -82    21
# Comp:  2               HeI5876     0.7611      0.19     -82    21
# Comp:  2          [OIII]5007_d      3.614      0.25     -82    21
# Comp:  2            [OI]6300_d      1.039      0.25     -82    21
# Comp:  2           [NII]6583_d      7.757      0.25     -82    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        24
#  comp.  1:       -80        32
#  comp.  2:       -82        13
# chi2/DOF: 0.9384; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.656      0.20     -80    32
# Comp:  1                Halpha      22.96      0.20     -80    32
# Comp:  2             [SII]6716      5.451      0.19     -82    13
# Comp:  2             [SII]6731      4.205      0.19     -82    13
# Comp:  2              HeII4687     0.7549      0.19     -82    13
# Comp:  2               HeI5876     0.8078      0.19     -82    13
# Comp:  2          [OIII]5007_d      3.382      0.24     -82    13
# Comp:  2            [OI]6300_d      1.072      0.24     -82    13
# Comp:  2           [NII]6583_d      7.668      0.24     -82    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -79        32
#  comp.  2:       -77        25
# chi2/DOF: 0.9327; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.659      0.20     -79    32
# Comp:  1                Halpha      22.98      0.20     -79    32
# Comp:  2             [SII]6716      5.487      0.20     -77    25
# Comp:  2             [SII]6731      4.266      0.20     -77    25
# Comp:  2              HeII4687     0.6800      0.20     -77    25
# Comp:  2               HeI5876     0.6360      0.20     -77    25
# Comp:  2          [OIII]5007_d      4.327      0.25     -77    25
# Comp:  2            [OI]6300_d     0.9382      0.25     -77    25
# Comp:  2           [NII]6583_d      7.466      0.25     -77    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -79        34
#  comp.  2:       -80        27
# chi2/DOF: 0.9337; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.911      0.20     -79    34
# Comp:  1                Halpha      22.99      0.20     -79    34
# Comp:  2             [SII]6716      5.616      0.20     -80    27
# Comp:  2             [SII]6731      4.549      0.20     -80    27
# Comp:  2              HeII4687     0.6921      0.20     -80    27
# Comp:  2               HeI5876     0.8705      0.20     -80    27
# Comp:  2          [OIII]5007_d      3.538      0.25     -80    27
# Comp:  2            [OI]6300_d     0.9906      0.25     -80    27
# Comp:  2           [NII]6583_d      7.724      0.25     -80    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -78        26
#  comp.  2:       -81        11
# chi2/DOF: 0.9400; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.691      0.20     -78    26
# Comp:  1                Halpha      22.20      0.20     -78    26
# Comp:  2             [SII]6716      5.212      0.19     -81    11
# Comp:  2             [SII]6731      4.148      0.19     -81    11
# Comp:  2              HeII4687     0.6404      0.19     -81    11
# Comp:  2               HeI5876     0.7033      0.19     -81    11
# Comp:  2          [OIII]5007_d      3.485      0.24     -81    11
# Comp:  2            [OI]6300_d      1.200      0.24     -81    11
# Comp:  2           [NII]6583_d      7.367      0.24     -81    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         2
#  comp.  1:       -78        28
#  comp.  2:       -79        28
# chi2/DOF: 0.9334; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.914      0.20     -78    28
# Comp:  1                Halpha      22.59      0.20     -78    28
# Comp:  2             [SII]6716      5.450      0.20     -79    28
# Comp:  2             [SII]6731      4.247      0.20     -79    28
# Comp:  2              HeII4687     0.7079      0.20     -79    28
# Comp:  2               HeI5876     0.7092      0.20     -79    28
# Comp:  2          [OIII]5007_d      3.492      0.25     -79    28
# Comp:  2            [OI]6300_d     0.8267      0.25     -79    28
# Comp:  2           [NII]6583_d      7.835      0.25     -79    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        46
#  comp.  1:       -78        32
#  comp.  2:       -80        13
# chi2/DOF: 0.9343; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.193      0.20     -78    32
# Comp:  1                Halpha      23.01      0.20     -78    32
# Comp:  2             [SII]6716      5.192      0.19     -80    13
# Comp:  2             [SII]6731      4.035      0.19     -80    13
# Comp:  2              HeII4687     0.6953      0.19     -80    13
# Comp:  2               HeI5876     0.7457      0.19     -80    13
# Comp:  2          [OIII]5007_d      3.588      0.24     -80    13
# Comp:  2            [OI]6300_d     0.7350      0.24     -80    13
# Comp:  2           [NII]6583_d      7.509      0.24     -80    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        26
#  comp.  1:       -80        29
#  comp.  2:       -81        17
# chi2/DOF: 0.9408; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.597      0.20     -80    29
# Comp:  1                Halpha      22.70      0.20     -80    29
# Comp:  2             [SII]6716      5.239      0.19     -81    17
# Comp:  2             [SII]6731      4.050      0.19     -81    17
# Comp:  2              HeII4687     0.6515      0.19     -81    17
# Comp:  2               HeI5876     0.6268      0.19     -81    17
# Comp:  2          [OIII]5007_d      4.130      0.24     -81    17
# Comp:  2            [OI]6300_d      1.122      0.24     -81    17
# Comp:  2           [NII]6583_d      7.576      0.24     -81    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -78        28
#  comp.  2:       -83        14
# chi2/DOF: 0.9428; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.630      0.20     -78    28
# Comp:  1                Halpha      22.16      0.20     -78    28
# Comp:  2             [SII]6716      5.304      0.19     -83    14
# Comp:  2             [SII]6731      4.107      0.19     -83    14
# Comp:  2              HeII4687     0.7254      0.19     -83    14
# Comp:  2               HeI5876     0.8131      0.19     -83    14
# Comp:  2          [OIII]5007_d      3.461      0.24     -83    14
# Comp:  2            [OI]6300_d      1.261      0.24     -83    14
# Comp:  2           [NII]6583_d      7.482      0.24     -83    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -78        26
#  comp.  2:       -79         4
# chi2/DOF: 0.9318; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.352      0.20     -78    26
# Comp:  1                Halpha      22.34      0.20     -78    26
# Comp:  2             [SII]6716      5.276      0.19     -79     4
# Comp:  2             [SII]6731      4.080      0.19     -79     4
# Comp:  2              HeII4687     0.6422      0.19     -79     4
# Comp:  2               HeI5876     0.7601      0.19     -79     4
# Comp:  2          [OIII]5007_d      3.948      0.24     -79     4
# Comp:  2            [OI]6300_d     0.9070      0.24     -79     4
# Comp:  2           [NII]6583_d      7.288      0.24     -79     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -80        31
#  comp.  2:       -82        23
# chi2/DOF: 0.9366; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.170      0.20     -80    31
# Comp:  1                Halpha      22.96      0.20     -80    31
# Comp:  2             [SII]6716      5.300      0.20     -82    23
# Comp:  2             [SII]6731      4.261      0.20     -82    23
# Comp:  2              HeII4687     0.7776      0.20     -82    23
# Comp:  2               HeI5876     0.7504      0.20     -82    23
# Comp:  2          [OIII]5007_d      4.257      0.25     -82    23
# Comp:  2            [OI]6300_d     0.8204      0.25     -82    23
# Comp:  2           [NII]6583_d      7.960      0.25     -82    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -78        28
#  comp.  2:       -81        13
# chi2/DOF: 0.9430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.573      0.20     -78    28
# Comp:  1                Halpha      22.56      0.20     -78    28
# Comp:  2             [SII]6716      5.158      0.19     -81    13
# Comp:  2             [SII]6731      4.222      0.19     -81    13
# Comp:  2              HeII4687     0.5353      0.19     -81    13
# Comp:  2               HeI5876     0.8317      0.19     -81    13
# Comp:  2          [OIII]5007_d      3.923      0.24     -81    13
# Comp:  2            [OI]6300_d     0.7512      0.24     -81    13
# Comp:  2           [NII]6583_d      7.456      0.24     -81    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        40
#  comp.  1:       -80        30
#  comp.  2:       -81        17
# chi2/DOF: 0.9456; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.705      0.20     -80    30
# Comp:  1                Halpha      22.68      0.20     -80    30
# Comp:  2             [SII]6716      5.301      0.19     -81    17
# Comp:  2             [SII]6731      4.326      0.19     -81    17
# Comp:  2              HeII4687     0.5756      0.19     -81    17
# Comp:  2               HeI5876     0.6503      0.19     -81    17
# Comp:  2          [OIII]5007_d      3.903      0.24     -81    17
# Comp:  2            [OI]6300_d     0.8949      0.24     -81    17
# Comp:  2           [NII]6583_d      7.740      0.24     -81    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -79        29
#  comp.  2:       -82        17
# chi2/DOF: 0.9314; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.614      0.20     -79    29
# Comp:  1                Halpha      22.83      0.20     -79    29
# Comp:  2             [SII]6716      5.331      0.19     -82    17
# Comp:  2             [SII]6731      4.437      0.19     -82    17
# Comp:  2              HeII4687     0.7546      0.19     -82    17
# Comp:  2               HeI5876     0.7298      0.19     -82    17
# Comp:  2          [OIII]5007_d      3.558      0.24     -82    17
# Comp:  2            [OI]6300_d     0.8665      0.24     -82    17
# Comp:  2           [NII]6583_d      7.540      0.24     -82    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        36
#  comp.  1:       -78        27
#  comp.  2:       -77        18
# chi2/DOF: 0.9320; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.325      0.20     -78    27
# Comp:  1                Halpha      22.34      0.20     -78    27
# Comp:  2             [SII]6716      5.420      0.19     -77    18
# Comp:  2             [SII]6731      4.179      0.19     -77    18
# Comp:  2              HeII4687     0.7163      0.19     -77    18
# Comp:  2               HeI5876     0.6093      0.19     -77    18
# Comp:  2          [OIII]5007_d      3.976      0.24     -77    18
# Comp:  2            [OI]6300_d     0.7501      0.24     -77    18
# Comp:  2           [NII]6583_d      7.653      0.24     -77    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -79        30
#  comp.  2:       -81         6
# chi2/DOF: 0.9455; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.054      0.20     -79    30
# Comp:  1                Halpha      22.72      0.20     -79    30
# Comp:  2             [SII]6716      5.239      0.19     -81     6
# Comp:  2             [SII]6731      3.994      0.19     -81     6
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.923      0.20     -77    31
# Comp:  1                Halpha      22.48      0.20     -77    31
# Comp:  2             [SII]6716      5.278      0.19     -78    14
# Comp:  2             [SII]6731      4.237      0.19     -78    14
# Comp:  2              HeII4687     0.6776      0.19     -78    14
# Comp:  2               HeI5876     0.6991      0.19     -78    14
# Comp:  2          [OIII]5007_d      3.232      0.24     -78    14
# Comp:  2            [OI]6300_d      1.064      0.24     -78    14
# Comp:  2           [NII]6583_d      7.450      0.24     -78    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -79        33
#  comp.  2:       -79        25
# chi2/DOF: 0.9426; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.832      0.20     -79    33
# Comp:  1                Halpha      22.89      0.20     -79    33
# Comp:  2             [SII]6716      5.374      0.20     -79    25
# Comp:  2             [SII]6731      4.227      0.20     -79    25
# Comp:  2              HeII4687     0.6873      0.20     -79    25
# Comp:  2               HeI5876     0.7366      0.20     -79    25
# Comp:  2          [OIII]5007_d      3.527      0.25     -79    25
# Comp:  2            [OI]6300_d      1.034      0.25     -79    25
# Comp:  2           [NII]6583_d      7.743      0.25     -79    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        25
#  comp.  1:       -79        32
#  comp.  2:       -80        18
# chi2/DOF: 0.9445; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.706      0.20     -79    32
# Comp:  1                Halpha      22.94      0.20     -79    32
# Comp:  2             [SII]6716      5.287      0.19     -80    18
# Comp:  2             [SII]6731      4.279      0.19     -80    18
# Comp:  2              HeII4687     0.6423      0.19     -80    18
# Comp:  2               HeI5876     0.8551      0.19     -80    18
# Comp:  2          [OIII]5007_d      3.838      0.24     -80    18
# Comp:  2            [OI]6300_d      1.007      0.24     -80    18
# Comp:  2           [NII]6583_d      7.631      0.24     -80    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -79        30
#  comp.  2:       -81         1
# chi2/DOF: 0.9440; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.699      0.20     -79    30
# Comp:  1                Halpha      22.74      0.20     -79    30
# Comp:  2             [SII]6716      5.260      0.19     -81     1
# Comp:  2             [SII]6731      4.233      0.19     -81     1
# Comp:  2              HeII4687     0.5730      0.19     -81     1
# Comp:  2               HeI5876     0.7008      0.19     -81     1
# Comp:  2          [OIII]5007_d      3.824      0.24     -81     1
# Comp:  2            [OI]6300_d     0.9705      0.24     -81     1
# Comp:  2           [NII]6583_d      7.516      0.24     -81     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        51
#  comp.  1:       -80        28
#  comp.  2:       -81        15
# chi2/DOF: 0.9295; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.582      0.20     -80    28
# Comp:  1                Halpha      22.72      0.20     -80    28
# Comp:  2             [SII]6716      5.276      0.19     -81    15
# Comp:  2             [SII]6731      4.338      0.19     -81    15
# Comp:  2              HeII4687     0.6578      0.19     -81    15
# Comp:  2               HeI5876     0.6551      0.19     -81    15
# Comp:  2          [OIII]5007_d      3.737      0.24     -81    15
# Comp:  2            [OI]6300_d     0.7726      0.24     -81    15
# Comp:  2           [NII]6583_d      7.526      0.24     -81    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        43
#  comp.  1:       -79        27
#  comp.  2:       -81         3
# chi2/DOF: 0.9340; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.484      0.20     -79    27
# Comp:  1                Halpha      22.48      0.20     -79    27
# Comp:  2             [SII]6716      5.195      0.19     -81     3
# Comp:  2             [SII]6731      4.193      0.19     -81     3
# Comp:  2              HeII4687     0.6315      0.19     -81     3
# Comp:  2               HeI5876     0.7538      0.19     -81     3
# Comp:  2          [OIII]5007_d      4.067      0.24     -81     3
# Comp:  2            [OI]6300_d     0.5450      0.24     -81     3
# Comp:  2           [NII]6583_d      7.643      0.24     -81     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -79        29
#  comp.  2:       -81        15
# chi2/DOF: 0.9443; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.520      0.20     -79    29
# Comp:  1                Halpha      22.33      0.20     -79    29
# Comp:  2             [SII]6716      5.226      0.19     -81    15
# Comp:  2             [SII]6731      4.205      0.19     -81    15
# Comp:  2              HeII4687     0.5603      0.19     -81    15
# Comp:  2               HeI5876     0.7402      0.19     -81    15
# Comp:  2          [OIII]5007_d      3.920      0.24     -81    15
# Comp:  2            [OI]6300_d     0.7484      0.24     -81    15
# Comp:  2           [NII]6583_d      7.781      0.24     -81    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        28
#  comp.  1:       -80        31
#  comp.  2:       -82        13
# chi2/DOF: 0.9391; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.177      0.20     -80    31
# Comp:  1                Halpha      23.11      0.20     -80    31
# Comp:  2             [SII]6716      5.344      0.19     -82    13
# Comp:  2             [SII]6731      4.133      0.19     -82    13
# Comp:  2              HeII4687     0.5725      0.19     -82    13
# Comp:  2               HeI5876     0.8368      0.19     -82    13
# Comp:  2          [OIII]5007_d      4.090      0.24     -82    13
# Comp:  2            [OI]6300_d     0.8848      0.24     -82    13
# Comp:  2           [NII]6583_d      7.632      0.24     -82    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        23
#  comp.  1:       -80        30
#  comp.  2:       -80        26
# chi2/DOF: 0.9346; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.385      0.20     -80    30
# Comp:  1                Halpha      22.68      0.20     -80    30
# Comp:  2             [SII]6716      5.439      0.20     -80    26
# Comp:  2             [SII]6731      4.451      0.20     -80    26
# Comp:  2              HeII4687     0.6587      0.20     -80    26
# Comp:  2               HeI5876     0.7590      0.20     -80    26
# Comp:  2          [OIII]5007_d      4.363      0.25     -80    26
# Comp:  2            [OI]6300_d     0.7609      0.25     -80    26
# Comp:  2           [NII]6583_d      7.478      0.25     -80    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        23
#  comp.  1:       -79        33
#  comp.  2:       -80         1
# chi2/DOF: 0.9424; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.532      0.20     -79    33
# Comp:  1                Halpha      22.87      0.20     -79    33
# Comp:  2             [SII]6716      5.235      0.19     -80     1
# Comp:  2             [SII]6731      4.118      0.19     -80     1
# Comp:  2              HeII4687     0.6894      0.19     -80     1
# Comp:  2               HeI5876     0.6891      0.19     -80     1
# Comp:  2          [OIII]5007_d      3.764      0.24     -80     1
# Comp:  2            [OI]6300_d      1.044      0.24     -80     1
# Comp:  2           [NII]6583_d      7.168      0.24     -80     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -78        31
#  comp.  2:       -81        19
# chi2/DOF: 0.9430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.476      0.20     -78    31
# Comp:  1                Halpha      22.41      0.20     -78    31
# Comp:  2             [SII]6716      5.361      0.19     -81    19
# Comp:  2             [SII]6731      4.214      0.19     -81    19
# Comp:  2              HeII4687     0.6240      0.19     -81    19
# Comp:  2               HeI5876     0.5892      0.19     -81    19
# Comp:  2          [OIII]5007_d      3.549      0.24     -81    19
# Comp:  2            [OI]6300_d     0.8558      0.24     -81    19
# Comp:  2           [NII]6583_d      7.746      0.24     -81    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -78        25
#  comp.  2:       -81        15
# chi2/DOF: 0.9373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.468      0.20     -78    25
# Comp:  1                Halpha      22.19      0.20     -78    25
# Comp:  2             [SII]6716      5.255      0.19     -81    15
# Comp:  2             [SII]6731      4.131      0.19     -81    15
# Comp:  2              HeII4687     0.6149      0.19     -81    15
# Comp:  2               HeI5876     0.6741      0.19     -81    15
# Comp:  2          [OIII]5007_d      3.683      0.24     -81    15
# Comp:  2            [OI]6300_d     0.9768      0.24     -81    15
# Comp:  2           [NII]6583_d      7.610      0.24     -81    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        14
#  comp.  1:       -79        29
#  comp.  2:       -81        16
# chi2/DOF: 0.9459; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.634      0.20     -79    29
# Comp:  1                Halpha      22.46      0.20     -79    29
# Comp:  2             [SII]6716      5.238      0.19     -81    16
# Comp:  2             [SII]6731      4.171      0.19     -81    16
# Comp:  2              HeII4687     0.6680      0.19     -81    16
# Comp:  2               HeI5876     0.6536      0.19     -81    16
# Comp:  2          [OIII]5007_d      4.103      0.24     -81    16
# Comp:  2            [OI]6300_d      1.211      0.24     -81    16
# Comp:  2           [NII]6583_d      7.231      0.24     -81    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -79        33
#  comp.  2:       -79        18
# chi2/DOF: 0.9384; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.723      0.20     -79    33
# Comp:  1                Halpha      23.01      0.20     -79    33
# Comp:  2             [SII]6716      5.440      0.19     -79    18
# Comp:  2             [SII]6731      4.231      0.19     -79    18
# Comp:  2              HeII4687     0.5625      0.19     -79    18
# Comp:  2               HeI5876     0.7209      0.19     -79    18
# Comp:  2          [OIII]5007_d      4.053      0.24     -79    18
# Comp:  2            [OI]6300_d      1.219      0.24     -79    18
# Comp:  2           [NII]6583_d      7.589      0.24     -79    18
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.60809942, 0.35437692, 0.13143876, 0.19206645, 0.05381158,
#        0.09280204, 0.26738619, 0.25391167, 0.25380153])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 5.60852191, 30.82068304,  7.43926247,  5.8780833 ,  0.63777924,
#         0.89944459,  3.97343031,  1.20647938, 10.37204621])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_14_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_14", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_14_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_14_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_14_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.291242    0.031578
# 1        Halpha  1.600472    0.018402
# 2     [SII]6716  0.386310    0.006825
# 3     [SII]6731  0.305240    0.009974
# 4      HeII4687  0.033119    0.002794
# 5       HeI5876  0.046707    0.004819
# 6  [OIII]5007_d  0.206334    0.013885
# 7    [OI]6300_d  0.062651    0.013185
# 8   [NII]6583_d  0.538605    0.013180
#           Name      Flux  Error_flux
# 0        Hbeta  0.291242    0.031578
# 1       Halpha  1.600472    0.018402
# 2    [SII]6716  0.386310    0.006825
# 3    [SII]6731  0.305240    0.009974
# 4     HeII4687  0.033119    0.002794
# 5      HeI5876  0.046707    0.004819
# 6   [OIII]4959  0.051584    0.013885
# 7   [OIII]5007  0.154751    0.013885
# 8     [OI]6300  0.046988    0.013185
# 9     [OI]6364  0.015663    0.013185
# 10   [NII]6548  0.134651    0.013180
# 11   [NII]6583  0.403954    0.013180

# %%
np.median(flux_rf_rebin)
# Out:
# 0.051928499943195566
