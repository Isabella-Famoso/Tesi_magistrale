# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_10.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_10']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.03980171 0.03286083 0.02647986 ... 0.03385943 0.03647195 0.03018484] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
# chi2/DOF: 0.01758; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         4
# chi2/DOF: 0.01235; DOF: 1918; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-47.73898969,   3.7981618 ])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        36
#  comp.  1:       -66        32
#  comp.  2:       -70        23
# chi2/DOF: 1.157; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.092      0.25     -66    32
# Comp:  1                Halpha      14.49      0.25     -66    32
# Comp:  2             [SII]6716      4.370      0.24     -70    23
# Comp:  2             [SII]6731      3.314      0.24     -70    23
# Comp:  2              HeII4687      0.000      0.24     -70    23
# Comp:  2               HeI5876     0.8523      0.24     -70    23
# Comp:  2          [OIII]5007_d      3.160      0.31     -70    23
# Comp:  2            [OI]6300_d      1.229      0.31     -70    23
# Comp:  2           [NII]6583_d      5.136      0.31     -70    23
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  14.02; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  40.15; gas flux:     20 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   13.1; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  9.358; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.631; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  7.311; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.692; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  11.23; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        77
#  comp.  1:       -68        36
#  comp.  2:       -66        21
# chi2/DOF: 1.146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.108      0.25     -68    36
# Comp:  1                Halpha      14.58      0.25     -68    36
# Comp:  2             [SII]6716      4.336      0.24     -66    21
# Comp:  2             [SII]6731      3.424      0.24     -66    21
# Comp:  2              HeII4687      0.000      0.24     -66    21
# Comp:  2               HeI5876     0.8900      0.24     -66    21
# Comp:  2          [OIII]5007_d      2.958      0.31     -66    21
# Comp:  2            [OI]6300_d      1.033      0.31     -66    21
# Comp:  2           [NII]6583_d      5.082      0.31     -66    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -63        33
#  comp.  2:       -71        30
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.970      0.25     -63    33
# Comp:  1                Halpha      14.38      0.25     -63    33
# Comp:  2             [SII]6716      4.619      0.25     -71    30
# Comp:  2             [SII]6731      3.425      0.25     -71    30
# Comp:  2              HeII4687      0.000      0.25     -71    30
# Comp:  2               HeI5876     0.8487      0.25     -71    30
# Comp:  2          [OIII]5007_d      3.645      0.31     -71    30
# Comp:  2            [OI]6300_d      1.309      0.31     -71    30
# Comp:  2           [NII]6583_d      5.081      0.31     -71    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        60
#  comp.  1:       -68        31
#  comp.  2:       -69        21
# chi2/DOF: 1.139; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.472      0.25     -68    31
# Comp:  1                Halpha      14.42      0.25     -68    31
# Comp:  2             [SII]6716      4.258      0.24     -69    21
# Comp:  2             [SII]6731      3.463      0.24     -69    21
# Comp:  2              HeII4687      0.000      0.24     -69    21
# Comp:  2               HeI5876     0.8739      0.24     -69    21
# Comp:  2          [OIII]5007_d      3.131      0.31     -69    21
# Comp:  2            [OI]6300_d      1.003      0.31     -69    21
# Comp:  2           [NII]6583_d      4.885      0.31     -69    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        52
#  comp.  1:       -66        31
#  comp.  2:       -71        10
# chi2/DOF: 1.147; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.783      0.25     -66    31
# Comp:  1                Halpha      14.60      0.25     -66    31
# Comp:  2             [SII]6716      4.475      0.24     -71    10
# Comp:  2             [SII]6731      3.194      0.24     -71    10
# Comp:  2              HeII4687     0.2843      0.24     -71    10
# Comp:  2               HeI5876     0.7907      0.24     -71    10
# Comp:  2          [OIII]5007_d      2.794      0.30     -71    10
# Comp:  2            [OI]6300_d      1.107      0.30     -71    10
# Comp:  2           [NII]6583_d      4.957      0.30     -71    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -67        30
#  comp.  2:       -72        30
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.535      0.25     -67    30
# Comp:  1                Halpha      14.44      0.25     -67    30
# Comp:  2             [SII]6716      4.396      0.25     -72    30
# Comp:  2             [SII]6731      3.237      0.25     -72    30
# Comp:  2              HeII4687      0.000      0.25     -72    30
# Comp:  2               HeI5876     0.8868      0.25     -72    30
# Comp:  2          [OIII]5007_d      3.201      0.31     -72    30
# Comp:  2            [OI]6300_d      1.185      0.31     -72    30
# Comp:  2           [NII]6583_d      5.325      0.31     -72    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         4
#  comp.  1:       -66        26
#  comp.  2:       -69        17
# chi2/DOF: 1.144; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.327      0.24     -66    26
# Comp:  1                Halpha      14.23      0.24     -66    26
# Comp:  2             [SII]6716      4.124      0.24     -69    17
# Comp:  2             [SII]6731      3.269      0.24     -69    17
# Comp:  2              HeII4687      0.000      0.24     -69    17
# Comp:  2               HeI5876     0.8393      0.24     -69    17
# Comp:  2          [OIII]5007_d      3.136      0.30     -69    17
# Comp:  2            [OI]6300_d      1.341      0.30     -69    17
# Comp:  2           [NII]6583_d      5.296      0.30     -69    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        18
#  comp.  1:       -65        30
#  comp.  2:       -72        22
# chi2/DOF: 1.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.115      0.25     -65    30
# Comp:  1                Halpha      14.35      0.25     -65    30
# Comp:  2             [SII]6716      4.523      0.24     -72    22
# Comp:  2             [SII]6731      3.311      0.24     -72    22
# Comp:  2              HeII4687     0.2209      0.24     -72    22
# Comp:  2               HeI5876     0.9222      0.24     -72    22
# Comp:  2          [OIII]5007_d      2.881      0.31     -72    22
# Comp:  2            [OI]6300_d      1.114      0.31     -72    22
# Comp:  2           [NII]6583_d      4.817      0.31     -72    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        43
#  comp.  1:       -66        31
#  comp.  2:       -71        19
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.828      0.25     -66    31
# Comp:  1                Halpha      14.45      0.25     -66    31
# Comp:  2             [SII]6716      4.268      0.24     -71    19
# Comp:  2             [SII]6731      3.180      0.24     -71    19
# Comp:  2              HeII4687      0.000      0.24     -71    19
# Comp:  2               HeI5876     0.7257      0.24     -71    19
# Comp:  2          [OIII]5007_d      3.313      0.30     -71    19
# Comp:  2            [OI]6300_d      1.400      0.30     -71    19
# Comp:  2           [NII]6583_d      5.077      0.30     -71    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        40
#  comp.  1:       -66        29
#  comp.  2:       -68        21
# chi2/DOF: 1.141; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.874      0.25     -66    29
# Comp:  1                Halpha      14.21      0.25     -66    29
# Comp:  2             [SII]6716      4.259      0.24     -68    21
# Comp:  2             [SII]6731      3.217      0.24     -68    21
# Comp:  2              HeII4687     0.2184      0.24     -68    21
# Comp:  2               HeI5876     0.9338      0.24     -68    21
# Comp:  2          [OIII]5007_d      2.697      0.30     -68    21
# Comp:  2            [OI]6300_d      1.478      0.30     -68    21
# Comp:  2           [NII]6583_d      5.060      0.30     -68    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        54
#  comp.  1:       -65        37
#  comp.  2:       -70        32
# chi2/DOF: 1.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.005      0.25     -65    37
# Comp:  1                Halpha      14.68      0.25     -65    37
# Comp:  2             [SII]6716      4.509      0.25     -70    32
# Comp:  2             [SII]6731      3.407      0.25     -70    32
# Comp:  2              HeII4687      0.000      0.25     -70    32
# Comp:  2               HeI5876     0.8353      0.25     -70    32
# Comp:  2          [OIII]5007_d      3.619      0.31     -70    32
# Comp:  2            [OI]6300_d      1.263      0.31     -70    32
# Comp:  2           [NII]6583_d      5.033      0.31     -70    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        63
#  comp.  1:       -67        32
#  comp.  2:       -73        16
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.657      0.25     -67    32
# Comp:  1                Halpha      14.60      0.25     -67    32
# Comp:  2             [SII]6716      4.508      0.24     -73    16
# Comp:  2             [SII]6731      3.280      0.24     -73    16
# Comp:  2              HeII4687     0.2959      0.24     -73    16
# Comp:  2               HeI5876     0.9502      0.24     -73    16
# Comp:  2          [OIII]5007_d      3.002      0.30     -73    16
# Comp:  2            [OI]6300_d      1.191      0.30     -73    16
# Comp:  2           [NII]6583_d      5.329      0.30     -73    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -68        33
#  comp.  2:       -75        12
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.264      0.25     -68    33
# Comp:  1                Halpha      14.47      0.25     -68    33
# Comp:  2             [SII]6716      4.176      0.24     -75    12
# Comp:  2             [SII]6731      3.260      0.24     -75    12
# Comp:  2              HeII4687      0.000      0.24     -75    12
# Comp:  2               HeI5876     0.8613      0.24     -75    12
# Comp:  2          [OIII]5007_d      3.292      0.30     -75    12
# Comp:  2            [OI]6300_d      1.313      0.30     -75    12
# Comp:  2           [NII]6583_d      5.056      0.30     -75    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -68        31
#  comp.  2:       -73        25
# chi2/DOF: 1.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.721      0.25     -68    31
# Comp:  1                Halpha      14.59      0.25     -68    31
# Comp:  2             [SII]6716      4.352      0.24     -73    25
# Comp:  2             [SII]6731      3.503      0.24     -73    25
# Comp:  2              HeII4687      0.000      0.24     -73    25
# Comp:  2               HeI5876     0.8122      0.24     -73    25
# Comp:  2          [OIII]5007_d      3.130      0.31     -73    25
# Comp:  2            [OI]6300_d     0.9034      0.31     -73    25
# Comp:  2           [NII]6583_d      5.231      0.31     -73    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        88
#  comp.  1:       -66        34
#  comp.  2:       -71        29
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.500      0.25     -66    34
# Comp:  1                Halpha      14.22      0.25     -66    34
# Comp:  2             [SII]6716      4.416      0.25     -71    29
# Comp:  2             [SII]6731      3.388      0.25     -71    29
# Comp:  2              HeII4687      0.000      0.25     -71    29
# Comp:  2               HeI5876      1.001      0.25     -71    29
# Comp:  2          [OIII]5007_d      2.771      0.31     -71    29
# Comp:  2            [OI]6300_d      1.363      0.31     -71    29
# Comp:  2           [NII]6583_d      5.063      0.31     -71    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        51
#  comp.  1:       -65        30
#  comp.  2:       -73        24
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.595      0.25     -65    30
# Comp:  1                Halpha      14.49      0.25     -65    30
# Comp:  2             [SII]6716      4.515      0.24     -73    24
# Comp:  2             [SII]6731      3.242      0.24     -73    24
# Comp:  2              HeII4687     0.2220      0.24     -73    24
# Comp:  2               HeI5876     0.9439      0.24     -73    24
# Comp:  2          [OIII]5007_d      3.572      0.31     -73    24
# Comp:  2            [OI]6300_d      1.159      0.31     -73    24
# Comp:  2           [NII]6583_d      5.338      0.31     -73    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        40
#  comp.  1:       -66        29
#  comp.  2:       -69        37
# chi2/DOF: 1.150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.380      0.25     -66    29
# Comp:  1                Halpha      14.06      0.25     -66    29
# Comp:  2             [SII]6716      4.407      0.25     -69    37
# Comp:  2             [SII]6731      3.399      0.25     -69    37
# Comp:  2              HeII4687      0.000      0.25     -69    37
# Comp:  2               HeI5876     0.7669      0.25     -69    37
# Comp:  2          [OIII]5007_d      3.573      0.32     -69    37
# Comp:  2            [OI]6300_d      1.301      0.32     -69    37
# Comp:  2           [NII]6583_d      5.274      0.32     -69    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        34
#  comp.  1:       -66        29
#  comp.  2:       -70         1
# chi2/DOF: 1.143; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.577      0.25     -66    29
# Comp:  1                Halpha      14.42      0.25     -66    29
# Comp:  2             [SII]6716      4.104      0.24     -70     1
# Comp:  2             [SII]6731      3.126      0.24     -70     1
# Comp:  2              HeII4687     0.1436      0.24     -70     1
# Comp:  2               HeI5876     0.7997      0.24     -70     1
# Comp:  2          [OIII]5007_d      3.015      0.30     -70     1
# Comp:  2            [OI]6300_d      1.197      0.30     -70     1
# Comp:  2           [NII]6583_d      5.151      0.30     -70     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        75
#  comp.  1:       -66        38
#  comp.  2:       -69        26
# chi2/DOF: 1.135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.328      0.25     -66    38
# Comp:  1                Halpha      14.62      0.25     -66    38
# Comp:  2             [SII]6716      4.417      0.24     -69    26
# Comp:  2             [SII]6731      3.231      0.24     -69    26
# Comp:  2              HeII4687      0.000      0.24     -69    26
# Comp:  2               HeI5876     0.8666      0.24     -69    26
# Comp:  2          [OIII]5007_d      3.514      0.31     -69    26
# Comp:  2            [OI]6300_d      1.194      0.31     -69    26
# Comp:  2           [NII]6583_d      5.144      0.31     -69    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        41
#  comp.  1:       -67        36
#  comp.  2:       -70        26
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.022      0.25     -67    36
# Comp:  1                Halpha      14.78      0.25     -67    36
# Comp:  2             [SII]6716      4.421      0.24     -70    26
# Comp:  2             [SII]6731      3.317      0.24     -70    26
# Comp:  2              HeII4687      0.000      0.24     -70    26
# Comp:  2               HeI5876     0.8568      0.24     -70    26
# Comp:  2          [OIII]5007_d      3.449      0.31     -70    26
# Comp:  2            [OI]6300_d      1.543      0.31     -70    26
# Comp:  2           [NII]6583_d      5.088      0.31     -70    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        60
#  comp.  1:       -67        35
#  comp.  2:       -71        20
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.590      0.25     -67    35
# Comp:  1                Halpha      14.44      0.25     -67    35
# Comp:  2             [SII]6716      4.299      0.24     -71    20
# Comp:  2             [SII]6731      3.383      0.24     -71    20
# Comp:  2              HeII4687     0.4026      0.24     -71    20
# Comp:  2               HeI5876     0.8286      0.24     -71    20
# Comp:  2          [OIII]5007_d      2.887      0.30     -71    20
# Comp:  2            [OI]6300_d      1.518      0.30     -71    20
# Comp:  2           [NII]6583_d      4.949      0.30     -71    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        66
#  comp.  1:       -68        29
#  comp.  2:       -68        32
# chi2/DOF: 1.139; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.835      0.25     -68    29
# Comp:  1                Halpha      14.46      0.25     -68    29
# Comp:  2             [SII]6716      4.427      0.25     -68    32
# Comp:  2             [SII]6731      3.544      0.25     -68    32
# Comp:  2              HeII4687     0.2338      0.25     -68    32
# Comp:  2               HeI5876     0.9561      0.25     -68    32
# Comp:  2          [OIII]5007_d      3.534      0.31     -68    32
# Comp:  2            [OI]6300_d      1.361      0.31     -68    32
# Comp:  2           [NII]6583_d      5.159      0.31     -68    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        41
#  comp.  1:       -66        33
#  comp.  2:       -71        29
# chi2/DOF: 1.146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.467      0.25     -66    33
# Comp:  1                Halpha      14.60      0.25     -66    33
# Comp:  2             [SII]6716      4.604      0.25     -71    29
# Comp:  2             [SII]6731      3.307      0.25     -71    29
# Comp:  2              HeII4687     0.2798      0.25     -71    29
# Comp:  2               HeI5876     0.9022      0.25     -71    29
# Comp:  2          [OIII]5007_d      3.381      0.31     -71    29
# Comp:  2            [OI]6300_d      1.478      0.31     -71    29
# Comp:  2           [NII]6583_d      5.112      0.31     -71    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -67        35
#  comp.  2:       -71        36
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.360      0.25     -67    35
# Comp:  1                Halpha      14.55      0.25     -67    35
# Comp:  2             [SII]6716      4.721      0.25     -71    36
# Comp:  2             [SII]6731      3.523      0.25     -71    36
# Comp:  2              HeII4687     0.5321      0.25     -71    36
# Comp:  2               HeI5876     0.8167      0.25     -71    36
# Comp:  2          [OIII]5007_d      3.841      0.32     -71    36
# Comp:  2            [OI]6300_d      1.301      0.32     -71    36
# Comp:  2           [NII]6583_d      5.554      0.32     -71    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        31
#  comp.  1:       -69        29
#  comp.  2:       -72        25
# chi2/DOF: 1.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.019      0.25     -69    29
# Comp:  1                Halpha      14.34      0.25     -69    29
# Comp:  2             [SII]6716      4.319      0.24     -72    25
# Comp:  2             [SII]6731      3.252      0.24     -72    25
# Comp:  2              HeII4687     0.3192      0.24     -72    25
# Comp:  2               HeI5876     0.8539      0.24     -72    25
# Comp:  2          [OIII]5007_d      3.138      0.31     -72    25
# Comp:  2            [OI]6300_d      1.199      0.31     -72    25
# Comp:  2           [NII]6583_d      4.918      0.31     -72    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         7
#  comp.  1:       -65        32
#  comp.  2:       -71        28
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.221      0.25     -65    32
# Comp:  1                Halpha      14.28      0.25     -65    32
# Comp:  2             [SII]6716      4.462      0.25     -71    28
# Comp:  2             [SII]6731      3.270      0.25     -71    28
# Comp:  2              HeII4687      0.000      0.25     -71    28
# Comp:  2               HeI5876     0.9493      0.25     -71    28
# Comp:  2          [OIII]5007_d      3.338      0.31     -71    28
# Comp:  2            [OI]6300_d      1.220      0.31     -71    28
# Comp:  2           [NII]6583_d      5.336      0.31     -71    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        36
#  comp.  1:       -66        30
#  comp.  2:       -71        20
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.442      0.25     -66    30
# Comp:  1                Halpha      14.28      0.25     -66    30
# Comp:  2             [SII]6716      4.316      0.24     -71    20
# Comp:  2             [SII]6731      3.264      0.24     -71    20
# Comp:  2              HeII4687     0.4199      0.24     -71    20
# Comp:  2               HeI5876     0.9694      0.24     -71    20
# Comp:  2          [OIII]5007_d      3.220      0.30     -71    20
# Comp:  2            [OI]6300_d      1.035      0.30     -71    20
# Comp:  2           [NII]6583_d      4.930      0.30     -71    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        22
#  comp.  1:       -69        32
#  comp.  2:       -68        24
# chi2/DOF: 1.152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.484      0.25     -69    32
# Comp:  1                Halpha      14.73      0.25     -69    32
# Comp:  2             [SII]6716      4.360      0.24     -68    24
# Comp:  2             [SII]6731      3.257      0.24     -68    24
# Comp:  2              HeII4687    0.06892      0.24     -68    24
# Comp:  2               HeI5876     0.8210      0.24     -68    24
# Comp:  2          [OIII]5007_d      2.906      0.31     -68    24
# Comp:  2            [OI]6300_d      1.130      0.31     -68    24
# Comp:  2           [NII]6583_d      5.027      0.31     -68    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        53
#  comp.  1:       -68        29
#  comp.  2:       -73        18
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.376      0.25     -68    29
# Comp:  1                Halpha      14.26      0.25     -68    29
# Comp:  2             [SII]6716      4.364      0.24     -73    18
# Comp:  2             [SII]6731      3.423      0.24     -73    18
# Comp:  2              HeII4687      0.000      0.24     -73    18
# Comp:  2               HeI5876     0.9614      0.24     -73    18
# Comp:  2          [OIII]5007_d      3.208      0.30     -73    18
# Comp:  2            [OI]6300_d      1.386      0.30     -73    18
# Comp:  2           [NII]6583_d      5.199      0.30     -73    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -68        30
#  comp.  2:       -68        17
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.605      0.25     -68    30
# Comp:  1                Halpha      14.36      0.25     -68    30
# Comp:  2             [SII]6716      4.188      0.24     -68    17
# Comp:  2             [SII]6731      3.268      0.24     -68    17
# Comp:  2              HeII4687     0.1052      0.24     -68    17
# Comp:  2               HeI5876     0.8941      0.24     -68    17
# Comp:  2          [OIII]5007_d      2.692      0.30     -68    17
# Comp:  2            [OI]6300_d      1.159      0.30     -68    17
# Comp:  2           [NII]6583_d      5.275      0.30     -68    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        25
#  comp.  1:       -65        28
#  comp.  2:       -68        27
# chi2/DOF: 1.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.043      0.25     -65    28
# Comp:  1                Halpha      14.62      0.25     -65    28
# Comp:  2             [SII]6716      4.365      0.25     -68    27
# Comp:  2             [SII]6731      3.327      0.25     -68    27
# Comp:  2              HeII4687      0.000      0.25     -68    27
# Comp:  2               HeI5876     0.8184      0.25     -68    27
# Comp:  2          [OIII]5007_d      3.237      0.31     -68    27
# Comp:  2            [OI]6300_d      1.232      0.31     -68    27
# Comp:  2           [NII]6583_d      5.321      0.31     -68    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        42
#  comp.  1:       -65        33
#  comp.  2:       -70        32
# chi2/DOF: 1.152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.191      0.25     -65    33
# Comp:  1                Halpha      14.48      0.25     -65    33
# Comp:  2             [SII]6716      4.400      0.25     -70    32
# Comp:  2             [SII]6731      3.592      0.25     -70    32
# Comp:  2              HeII4687      0.000      0.25     -70    32
# Comp:  2               HeI5876     0.8459      0.25     -70    32
# Comp:  2          [OIII]5007_d      3.199      0.31     -70    32
# Comp:  2            [OI]6300_d      1.322      0.31     -70    32
# Comp:  2           [NII]6583_d      5.255      0.31     -70    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -66        31
#  comp.  2:       -68        16
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.391      0.25     -66    31
# Comp:  1                Halpha      14.83      0.25     -66    31
# Comp:  2             [SII]6716      4.029      0.24     -68    16
# Comp:  2             [SII]6731      3.268      0.24     -68    16
# Comp:  2              HeII4687     0.4168      0.24     -68    16
# Comp:  2               HeI5876     0.8078      0.24     -68    16
# Comp:  2          [OIII]5007_d      2.965      0.30     -68    16
# Comp:  2            [OI]6300_d      1.290      0.30     -68    16
# Comp:  2           [NII]6583_d      5.087      0.30     -68    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        34
#  comp.  1:       -66        25
#  comp.  2:       -70         1
# chi2/DOF: 1.144; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.273      0.24     -66    25
# Comp:  1                Halpha      14.00      0.24     -66    25
# Comp:  2             [SII]6716      4.028      0.24     -70     1
# Comp:  2             [SII]6731      3.124      0.24     -70     1
# Comp:  2              HeII4687     0.1715      0.24     -70     1
# Comp:  2               HeI5876     0.9136      0.24     -70     1
# Comp:  2          [OIII]5007_d      3.050      0.30     -70     1
# Comp:  2            [OI]6300_d      1.050      0.30     -70     1
# Comp:  2           [NII]6583_d      4.960      0.30     -70     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -64        32
#  comp.  2:       -72         4
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.376      0.25     -64    32
# Comp:  1                Halpha      14.80      0.25     -64    32
# Comp:  2             [SII]6716      4.286      0.24     -72     4
# Comp:  2             [SII]6731      3.227      0.24     -72     4
# Comp:  2              HeII4687      0.000      0.24     -72     4
# Comp:  2               HeI5876     0.7073      0.24     -72     4
# Comp:  2          [OIII]5007_d      3.344      0.30     -72     4
# Comp:  2            [OI]6300_d     0.8841      0.30     -72     4
# Comp:  2           [NII]6583_d      4.775      0.30     -72     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -67        32
#  comp.  2:       -73        32
# chi2/DOF: 1.142; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.418      0.25     -67    32
# Comp:  1                Halpha      14.62      0.25     -67    32
# Comp:  2             [SII]6716      4.388      0.25     -73    32
# Comp:  2             [SII]6731      3.189      0.25     -73    32
# Comp:  2              HeII4687     0.1745      0.25     -73    32
# Comp:  2               HeI5876     0.9765      0.25     -73    32
# Comp:  2          [OIII]5007_d      3.774      0.31     -73    32
# Comp:  2            [OI]6300_d      1.573      0.31     -73    32
# Comp:  2           [NII]6583_d      5.217      0.31     -73    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        45
#  comp.  1:       -64        35
#  comp.  2:       -69        28
# chi2/DOF: 1.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.709      0.25     -64    35
# Comp:  1                Halpha      14.58      0.25     -64    35
# Comp:  2             [SII]6716      4.426      0.25     -69    28
# Comp:  2             [SII]6731      3.482      0.25     -69    28
# Comp:  2              HeII4687      0.000      0.25     -69    28
# Comp:  2               HeI5876     0.8798      0.25     -69    28
# Comp:  2          [OIII]5007_d      3.033      0.31     -69    28
# Comp:  2            [OI]6300_d      1.478      0.31     -69    28
# Comp:  2           [NII]6583_d      5.359      0.31     -69    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        40
#  comp.  1:       -67        37
#  comp.  2:       -73        15
# chi2/DOF: 1.150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.188      0.25     -67    37
# Comp:  1                Halpha      14.92      0.25     -67    37
# Comp:  2             [SII]6716      4.390      0.24     -73    15
# Comp:  2             [SII]6731      3.144      0.24     -73    15
# Comp:  2              HeII4687      0.000      0.24     -73    15
# Comp:  2               HeI5876     0.9423      0.24     -73    15
# Comp:  2          [OIII]5007_d      3.169      0.30     -73    15
# Comp:  2            [OI]6300_d      1.005      0.30     -73    15
# Comp:  2           [NII]6583_d      5.276      0.30     -73    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        15
#  comp.  1:       -65        31
#  comp.  2:       -68        23
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.598      0.25     -65    31
# Comp:  1                Halpha      14.26      0.25     -65    31
# Comp:  2             [SII]6716      4.313      0.24     -68    23
# Comp:  2             [SII]6731      3.326      0.24     -68    23
# Comp:  2              HeII4687      0.000      0.24     -68    23
# Comp:  2               HeI5876     0.8902      0.24     -68    23
# Comp:  2          [OIII]5007_d      3.284      0.31     -68    23
# Comp:  2            [OI]6300_d      1.386      0.31     -68    23
# Comp:  2           [NII]6583_d      5.207      0.31     -68    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        12
#  comp.  1:       -65        31
#  comp.  2:       -69        25
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.297      0.25     -65    31
# Comp:  1                Halpha      14.62      0.25     -65    31
# Comp:  2             [SII]6716      4.549      0.24     -69    25
# Comp:  2             [SII]6731      3.347      0.24     -69    25
# Comp:  2              HeII4687      0.000      0.24     -69    25
# Comp:  2               HeI5876     0.9715      0.24     -69    25
# Comp:  2          [OIII]5007_d      3.476      0.31     -69    25
# Comp:  2            [OI]6300_d     0.7772      0.31     -69    25
# Comp:  2           [NII]6583_d      4.988      0.31     -69    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        36
#  comp.  1:       -65        35
#  comp.  2:       -71        33
# chi2/DOF: 1.147; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.338      0.25     -65    35
# Comp:  1                Halpha      14.57      0.25     -65    35
# Comp:  2             [SII]6716      4.501      0.25     -71    33
# Comp:  2             [SII]6731      3.282      0.25     -71    33
# Comp:  2              HeII4687      0.000      0.25     -71    33
# Comp:  2               HeI5876     0.8433      0.25     -71    33
# Comp:  2          [OIII]5007_d      3.250      0.31     -71    33
# Comp:  2            [OI]6300_d      1.011      0.31     -71    33
# Comp:  2           [NII]6583_d      5.137      0.31     -71    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        13
#  comp.  1:       -67        35
#  comp.  2:       -68        21
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.562      0.25     -67    35
# Comp:  1                Halpha      14.68      0.25     -67    35
# Comp:  2             [SII]6716      4.450      0.24     -68    21
# Comp:  2             [SII]6731      3.372      0.24     -68    21
# Comp:  2              HeII4687     0.1089      0.24     -68    21
# Comp:  2               HeI5876     0.8872      0.24     -68    21
# Comp:  2          [OIII]5007_d      3.107      0.30     -68    21
# Comp:  2            [OI]6300_d      1.355      0.30     -68    21
# Comp:  2           [NII]6583_d      4.971      0.30     -68    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        67
#  comp.  1:       -68        30
#  comp.  2:       -68        34
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.498      0.25     -68    30
# Comp:  1                Halpha      14.34      0.25     -68    30
# Comp:  2             [SII]6716      4.495      0.25     -68    34
# Comp:  2             [SII]6731      3.471      0.25     -68    34
# Comp:  2              HeII4687      0.000      0.25     -68    34
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.774      0.25     -65    35
# Comp:  1                Halpha      14.61      0.25     -65    35
# Comp:  2             [SII]6716      4.941      0.25     -66    38
# Comp:  2             [SII]6731      3.579      0.25     -66    38
# Comp:  2              HeII4687     0.2802      0.25     -66    38
# Comp:  2               HeI5876     0.8653      0.25     -66    38
# Comp:  2          [OIII]5007_d      3.110      0.32     -66    38
# Comp:  2            [OI]6300_d      1.634      0.32     -66    38
# Comp:  2           [NII]6583_d      5.359      0.32     -66    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        40
#  comp.  1:       -66        34
#  comp.  2:       -71        24
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.114      0.25     -66    34
# Comp:  1                Halpha      14.53      0.25     -66    34
# Comp:  2             [SII]6716      4.355      0.24     -71    24
# Comp:  2             [SII]6731      3.195      0.24     -71    24
# Comp:  2              HeII4687     0.1404      0.24     -71    24
# Comp:  2               HeI5876     0.8776      0.24     -71    24
# Comp:  2          [OIII]5007_d      3.385      0.31     -71    24
# Comp:  2            [OI]6300_d      1.422      0.31     -71    24
# Comp:  2           [NII]6583_d      4.967      0.31     -71    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -66        32
#  comp.  2:       -71        28
# chi2/DOF: 1.146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.011      0.25     -66    32
# Comp:  1                Halpha      14.63      0.25     -66    32
# Comp:  2             [SII]6716      4.589      0.25     -71    28
# Comp:  2             [SII]6731      3.475      0.25     -71    28
# Comp:  2              HeII4687      0.000      0.25     -71    28
# Comp:  2               HeI5876     0.9488      0.25     -71    28
# Comp:  2          [OIII]5007_d      3.382      0.31     -71    28
# Comp:  2            [OI]6300_d      1.214      0.31     -71    28
# Comp:  2           [NII]6583_d      5.554      0.31     -71    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        61
#  comp.  1:       -66        35
#  comp.  2:       -72        20
# chi2/DOF: 1.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.209      0.25     -66    35
# Comp:  1                Halpha      14.79      0.25     -66    35
# Comp:  2             [SII]6716      4.299      0.24     -72    20
# Comp:  2             [SII]6731      3.331      0.24     -72    20
# Comp:  2              HeII4687      0.000      0.24     -72    20
# Comp:  2               HeI5876     0.8201      0.24     -72    20
# Comp:  2          [OIII]5007_d      2.877      0.30     -72    20
# Comp:  2            [OI]6300_d      1.426      0.30     -72    20
# Comp:  2           [NII]6583_d      5.256      0.30     -72    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        19
#  comp.  1:       -68        26
#  comp.  2:       -74         9
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.451      0.24     -68    26
# Comp:  1                Halpha      14.41      0.24     -68    26
# Comp:  2             [SII]6716      4.357      0.24     -74     9
# Comp:  2             [SII]6731      3.252      0.24     -74     9
# Comp:  2              HeII4687      0.000      0.24     -74     9
# Comp:  2               HeI5876     0.7936      0.24     -74     9
# Comp:  2          [OIII]5007_d      3.233      0.30     -74     9
# Comp:  2            [OI]6300_d     0.9381      0.30     -74     9
# Comp:  2           [NII]6583_d      5.142      0.30     -74     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -67        25
#  comp.  2:       -71        22
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.006      0.24     -67    25
# Comp:  1                Halpha      14.30      0.24     -67    25
# Comp:  2             [SII]6716      4.518      0.24     -71    22
# Comp:  2             [SII]6731      3.338      0.24     -71    22
# Comp:  2              HeII4687      0.000      0.24     -71    22
# Comp:  2               HeI5876      1.010      0.24     -71    22
# Comp:  2          [OIII]5007_d      3.270      0.31     -71    22
# Comp:  2            [OI]6300_d      1.006      0.31     -71    22
# Comp:  2           [NII]6583_d      5.139      0.31     -71    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        17
#  comp.  1:       -66        30
#  comp.  2:       -69        15
# chi2/DOF: 1.148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.115      0.25     -66    30
# Comp:  1                Halpha      14.42      0.25     -66    30
# Comp:  2             [SII]6716      4.247      0.24     -69    15
# Comp:  2             [SII]6731      3.250      0.24     -69    15
# Comp:  2              HeII4687      0.000      0.24     -69    15
# Comp:  2               HeI5876     0.9325      0.24     -69    15
# Comp:  2          [OIII]5007_d      3.518      0.30     -69    15
# Comp:  2            [OI]6300_d      1.116      0.30     -69    15
# Comp:  2           [NII]6583_d      5.239      0.30     -69    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        62
#  comp.  1:       -68        32
#  comp.  2:       -70        22
# chi2/DOF: 1.144; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.398      0.25     -68    32
# Comp:  1                Halpha      14.62      0.25     -68    32
# Comp:  2             [SII]6716      4.358      0.24     -70    22
# Comp:  2             [SII]6731      3.225      0.24     -70    22
# Comp:  2              HeII4687      0.000      0.24     -70    22
# Comp:  2               HeI5876     0.8670      0.24     -70    22
# Comp:  2          [OIII]5007_d      2.854      0.31     -70    22
# Comp:  2            [OI]6300_d     0.9375      0.31     -70    22
# Comp:  2           [NII]6583_d      5.162      0.31     -70    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         4
#  comp.  1:       -68        31
#  comp.  2:       -75        30
# chi2/DOF: 1.141; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.580      0.25     -68    31
# Comp:  1                Halpha      14.30      0.25     -68    31
# Comp:  2             [SII]6716      4.500      0.25     -75    30
# Comp:  2             [SII]6731      3.514      0.25     -75    30
# Comp:  2              HeII4687      0.000      0.25     -75    30
# Comp:  2               HeI5876      1.015      0.25     -75    30
# Comp:  2          [OIII]5007_d      3.329      0.31     -75    30
# Comp:  2            [OI]6300_d      1.312      0.31     -75    30
# Comp:  2           [NII]6583_d      5.153      0.31     -75    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        70
#  comp.  1:       -66        36
#  comp.  2:       -73        21
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.020      0.25     -66    36
# Comp:  1                Halpha      14.64      0.25     -66    36
# Comp:  2             [SII]6716      4.186      0.24     -73    21
# Comp:  2             [SII]6731      3.205      0.24     -73    21
# Comp:  2              HeII4687     0.1103      0.24     -73    21
# Comp:  2               HeI5876      1.028      0.24     -73    21
# Comp:  2          [OIII]5007_d      3.220      0.30     -73    21
# Comp:  2            [OI]6300_d      1.205      0.30     -73    21
# Comp:  2           [NII]6583_d      4.968      0.30     -73    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -65        34
#  comp.  2:       -66        31
# chi2/DOF: 1.144; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.479      0.25     -65    34
# Comp:  1                Halpha      14.51      0.25     -65    34
# Comp:  2             [SII]6716      4.457      0.25     -66    31
# Comp:  2             [SII]6731      3.580      0.25     -66    31
# Comp:  2              HeII4687      0.000      0.25     -66    31
# Comp:  2               HeI5876     0.9412      0.25     -66    31
# Comp:  2          [OIII]5007_d      2.695      0.31     -66    31
# Comp:  2            [OI]6300_d      1.114      0.31     -66    31
# Comp:  2           [NII]6583_d      5.491      0.31     -66    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        33
#  comp.  1:       -67        27
#  comp.  2:       -70        14
# chi2/DOF: 1.143; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.137      0.25     -67    27
# Comp:  1                Halpha      14.37      0.25     -67    27
# Comp:  2             [SII]6716      4.299      0.24     -70    14
# Comp:  2             [SII]6731      3.215      0.24     -70    14
# Comp:  2              HeII4687      0.000      0.24     -70    14
# Comp:  2               HeI5876     0.9061      0.24     -70    14
# Comp:  2          [OIII]5007_d      3.048      0.30     -70    14
# Comp:  2            [OI]6300_d      1.275      0.30     -70    14
# Comp:  2           [NII]6583_d      4.994      0.30     -70    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        16
#  comp.  1:       -65        32
#  comp.  2:       -74        22
# chi2/DOF: 1.145; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.527      0.25     -65    32
# Comp:  1                Halpha      14.51      0.25     -65    32
# Comp:  2             [SII]6716      4.226      0.24     -74    22
# Comp:  2             [SII]6731      3.180      0.24     -74    22
# Comp:  2              HeII4687     0.2641      0.24     -74    22
# Comp:  2               HeI5876     0.8779      0.24     -74    22
# Comp:  2          [OIII]5007_d      3.199      0.31     -74    22
# Comp:  2            [OI]6300_d      1.412      0.31     -74    22
# Comp:  2           [NII]6583_d      4.845      0.31     -74    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -67        38
#  comp.  2:       -72        32
# chi2/DOF: 1.146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.772      0.25     -67    38
# Comp:  1                Halpha      15.09      0.25     -67    38
# Comp:  2             [SII]6716      4.582      0.25     -72    32
# Comp:  2             [SII]6731      3.615      0.25     -72    32
# Comp:  2              HeII4687    0.03873      0.25     -72    32
# Comp:  2               HeI5876     0.9846      0.25     -72    32
# Comp:  2          [OIII]5007_d      3.177      0.31     -72    32
# Comp:  2            [OI]6300_d      1.366      0.31     -72    32
# Comp:  2           [NII]6583_d      5.397      0.31     -72    32
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.48408552, 0.36368424, 0.23293105, 0.18415391, 0.14798022,
#        0.08291863, 0.27790768, 0.29729733, 0.23836183])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 5.16282573, 19.82917463,  6.12167221,  4.6518334 ,  0.        ,
#         1.04446357,  3.29991812,  1.61445811,  7.05251723])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_10_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_10", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_10_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_10_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_10_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.172923    0.016214
# 1        Halpha  0.664154    0.012181
# 2     [SII]6716  0.205038    0.007802
# 3     [SII]6731  0.155807    0.006168
# 4      HeII4687  0.000000    0.004956
# 5       HeI5876  0.034983    0.002777
# 6  [OIII]5007_d  0.110527    0.009308
# 7    [OI]6300_d  0.054074    0.009958
# 8   [NII]6583_d  0.236215    0.007984
#           Name      Flux  Error_flux
# 0        Hbeta  0.172923    0.016214
# 1       Halpha  0.664154    0.012181
# 2    [SII]6716  0.205038    0.007802
# 3    [SII]6731  0.155807    0.006168
# 4     HeII4687  0.000000    0.004956
# 5      HeI5876  0.034983    0.002777
# 6   [OIII]4959  0.027632    0.009308
# 7   [OIII]5007  0.082895    0.009308
# 8     [OI]6300  0.040556    0.009958
# 9     [OI]6364  0.013519    0.009958
# 10   [NII]6548  0.059054    0.007984
# 11   [NII]6583  0.177162    0.007984

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03349377590334081
