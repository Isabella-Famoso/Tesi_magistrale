# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.0284494  0.03543059 0.03553493 ... 0.02575069 0.02628023 0.02987396] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
# chi2/DOF: 0.02709; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        56
# chi2/DOF: 0.01642; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-38.51656142,  55.60536831])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        22
#  comp.  1:       -72        40
#  comp.  2:       -72        39
# chi2/DOF: 1.265; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.309      0.30     -72    40
# Comp:  1                Halpha      12.04      0.30     -72    40
# Comp:  2             [SII]6716      3.869      0.30     -72    39
# Comp:  2             [SII]6731      3.356      0.30     -72    39
# Comp:  2              HeII4687      0.000      0.30     -72    39
# Comp:  2               HeI5876      1.304      0.30     -72    39
# Comp:  2          [OIII]5007_d      5.948      0.37     -72    39
# Comp:  2            [OI]6300_d      1.176      0.37     -72    39
# Comp:  2           [NII]6583_d      4.486      0.37     -72    39
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  7.586; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  28.81; gas flux:     16 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.449; gas flux:      5 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  7.723; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.254; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  11.11; gas flux:      6 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.091; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  8.039; gas flux:      6 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        19
#  comp.  1:       -73        41
#  comp.  2:       -81        37
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.069      0.30     -73    41
# Comp:  1                Halpha      12.14      0.30     -73    41
# Comp:  2             [SII]6716      3.817      0.29     -81    37
# Comp:  2             [SII]6731      3.412      0.29     -81    37
# Comp:  2              HeII4687      0.000      0.29     -81    37
# Comp:  2               HeI5876      1.276      0.29     -81    37
# Comp:  2          [OIII]5007_d      5.915      0.37     -81    37
# Comp:  2            [OI]6300_d     0.8963      0.37     -81    37
# Comp:  2           [NII]6583_d      4.610      0.37     -81    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:       -71        41
#  comp.  2:       -70        36
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.165      0.30     -71    41
# Comp:  1                Halpha      12.22      0.30     -71    41
# Comp:  2             [SII]6716      3.848      0.29     -70    36
# Comp:  2             [SII]6731      3.018      0.29     -70    36
# Comp:  2              HeII4687      0.000      0.29     -70    36
# Comp:  2               HeI5876      1.191      0.29     -70    36
# Comp:  2          [OIII]5007_d      5.046      0.37     -70    36
# Comp:  2            [OI]6300_d      1.201      0.37     -70    36
# Comp:  2           [NII]6583_d      4.762      0.37     -70    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -71        36
#  comp.  2:       -69        46
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.342      0.29     -71    36
# Comp:  1                Halpha      11.80      0.29     -71    36
# Comp:  2             [SII]6716      3.900      0.30     -69    46
# Comp:  2             [SII]6731      3.562      0.30     -69    46
# Comp:  2              HeII4687      0.000      0.30     -69    46
# Comp:  2               HeI5876      1.456      0.30     -69    46
# Comp:  2          [OIII]5007_d      5.426      0.38     -69    46
# Comp:  2            [OI]6300_d     0.9325      0.38     -69    46
# Comp:  2           [NII]6583_d      4.671      0.38     -69    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        20
#  comp.  1:       -70        40
#  comp.  2:       -78        37
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.448      0.30     -70    40
# Comp:  1                Halpha      12.15      0.30     -70    40
# Comp:  2             [SII]6716      3.764      0.29     -78    37
# Comp:  2             [SII]6731      3.351      0.29     -78    37
# Comp:  2              HeII4687     0.2115      0.29     -78    37
# Comp:  2               HeI5876      1.217      0.29     -78    37
# Comp:  2          [OIII]5007_d      6.083      0.37     -78    37
# Comp:  2            [OI]6300_d      1.001      0.37     -78    37
# Comp:  2           [NII]6583_d      4.554      0.37     -78    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        43
#  comp.  1:       -72        43
#  comp.  2:       -75        30
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.803      0.30     -72    43
# Comp:  1                Halpha      12.32      0.30     -72    43
# Comp:  2             [SII]6716      3.898      0.29     -75    30
# Comp:  2             [SII]6731      3.188      0.29     -75    30
# Comp:  2              HeII4687      0.000      0.29     -75    30
# Comp:  2               HeI5876      1.353      0.29     -75    30
# Comp:  2          [OIII]5007_d      6.515      0.36     -75    30
# Comp:  2            [OI]6300_d      1.181      0.36     -75    30
# Comp:  2           [NII]6583_d      4.394      0.36     -75    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        49
#  comp.  1:       -71        38
#  comp.  2:       -66        49
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.251      0.29     -71    38
# Comp:  1                Halpha      11.90      0.29     -71    38
# Comp:  2             [SII]6716      3.946      0.31     -66    49
# Comp:  2             [SII]6731      3.512      0.31     -66    49
# Comp:  2              HeII4687      0.000      0.31     -66    49
# Comp:  2               HeI5876      1.263      0.31     -66    49
# Comp:  2          [OIII]5007_d      5.517      0.39     -66    49
# Comp:  2            [OI]6300_d     0.9996      0.39     -66    49
# Comp:  2           [NII]6583_d      4.378      0.39     -66    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -72        39
#  comp.  2:       -74        30
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.852      0.30     -72    39
# Comp:  1                Halpha      12.20      0.30     -72    39
# Comp:  2             [SII]6716      3.629      0.29     -74    30
# Comp:  2             [SII]6731      3.327      0.29     -74    30
# Comp:  2              HeII4687    0.08788      0.29     -74    30
# Comp:  2               HeI5876      1.345      0.29     -74    30
# Comp:  2          [OIII]5007_d      6.425      0.36     -74    30
# Comp:  2            [OI]6300_d      1.213      0.36     -74    30
# Comp:  2           [NII]6583_d      4.850      0.36     -74    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        21
#  comp.  1:       -73        42
#  comp.  2:       -67        45
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.702      0.30     -73    42
# Comp:  1                Halpha      12.14      0.30     -73    42
# Comp:  2             [SII]6716      3.764      0.30     -67    45
# Comp:  2             [SII]6731      3.406      0.30     -67    45
# Comp:  2              HeII4687      0.000      0.30     -67    45
# Comp:  2               HeI5876      1.253      0.30     -67    45
# Comp:  2          [OIII]5007_d      5.343      0.38     -67    45
# Comp:  2            [OI]6300_d      1.425      0.38     -67    45
# Comp:  2           [NII]6583_d      4.572      0.38     -67    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        35
#  comp.  1:       -71        41
#  comp.  2:       -72        32
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.821      0.30     -71    41
# Comp:  1                Halpha      12.27      0.30     -71    41
# Comp:  2             [SII]6716      3.803      0.29     -72    32
# Comp:  2             [SII]6731      3.268      0.29     -72    32
# Comp:  2              HeII4687    0.04303      0.29     -72    32
# Comp:  2               HeI5876      1.277      0.29     -72    32
# Comp:  2          [OIII]5007_d      6.623      0.36     -72    32
# Comp:  2            [OI]6300_d      1.075      0.36     -72    32
# Comp:  2           [NII]6583_d      4.595      0.36     -72    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        59
#  comp.  1:       -72        38
#  comp.  2:       -72        36
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.605      0.29     -72    38
# Comp:  1                Halpha      11.78      0.29     -72    38
# Comp:  2             [SII]6716      3.940      0.29     -72    36
# Comp:  2             [SII]6731      3.430      0.29     -72    36
# Comp:  2              HeII4687      0.000      0.29     -72    36
# Comp:  2               HeI5876      1.216      0.29     -72    36
# Comp:  2          [OIII]5007_d      4.921      0.37     -72    36
# Comp:  2            [OI]6300_d      1.325      0.37     -72    36
# Comp:  2           [NII]6583_d      4.719      0.37     -72    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        24
#  comp.  1:       -71        41
#  comp.  2:       -68        26
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.635      0.30     -71    41
# Comp:  1                Halpha      12.02      0.30     -71    41
# Comp:  2             [SII]6716      3.583      0.28     -68    26
# Comp:  2             [SII]6731      3.000      0.28     -68    26
# Comp:  2              HeII4687     0.1651      0.28     -68    26
# Comp:  2               HeI5876      1.349      0.28     -68    26
# Comp:  2          [OIII]5007_d      5.637      0.36     -68    26
# Comp:  2            [OI]6300_d      1.195      0.36     -68    26
# Comp:  2           [NII]6583_d      3.931      0.36     -68    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -74        44
#  comp.  2:       -71        40
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.799      0.30     -74    44
# Comp:  1                Halpha      12.26      0.30     -74    44
# Comp:  2             [SII]6716      3.872      0.30     -71    40
# Comp:  2             [SII]6731      3.366      0.30     -71    40
# Comp:  2              HeII4687      0.000      0.30     -71    40
# Comp:  2               HeI5876      1.148      0.30     -71    40
# Comp:  2          [OIII]5007_d      5.115      0.37     -71    40
# Comp:  2            [OI]6300_d      1.073      0.37     -71    40
# Comp:  2           [NII]6583_d      4.628      0.37     -71    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         6
#  comp.  1:       -72        40
#  comp.  2:       -77        34
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.777      0.30     -72    40
# Comp:  1                Halpha      12.20      0.30     -72    40
# Comp:  2             [SII]6716      4.001      0.29     -77    34
# Comp:  2             [SII]6731      3.416      0.29     -77    34
# Comp:  2              HeII4687      0.000      0.29     -77    34
# Comp:  2               HeI5876      1.368      0.29     -77    34
# Comp:  2          [OIII]5007_d      6.623      0.37     -77    34
# Comp:  2            [OI]6300_d      1.033      0.37     -77    34
# Comp:  2           [NII]6583_d      4.509      0.37     -77    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        49
#  comp.  1:       -73        41
#  comp.  2:       -74        41
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.501      0.30     -73    41
# Comp:  1                Halpha      12.04      0.30     -73    41
# Comp:  2             [SII]6716      4.177      0.30     -74    41
# Comp:  2             [SII]6731      3.690      0.30     -74    41
# Comp:  2              HeII4687      0.000      0.30     -74    41
# Comp:  2               HeI5876      1.250      0.30     -74    41
# Comp:  2          [OIII]5007_d      6.929      0.38     -74    41
# Comp:  2            [OI]6300_d      1.136      0.38     -74    41
# Comp:  2           [NII]6583_d      4.700      0.38     -74    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        75
#  comp.  1:       -70        42
#  comp.  2:       -69        27
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.649      0.30     -70    42
# Comp:  1                Halpha      12.47      0.30     -70    42
# Comp:  2             [SII]6716      3.884      0.29     -69    27
# Comp:  2             [SII]6731      2.987      0.29     -69    27
# Comp:  2              HeII4687     0.2748      0.29     -69    27
# Comp:  2               HeI5876      1.275      0.29     -69    27
# Comp:  2          [OIII]5007_d      5.376      0.36     -69    27
# Comp:  2            [OI]6300_d      1.063      0.36     -69    27
# Comp:  2           [NII]6583_d      4.192      0.36     -69    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        66
#  comp.  1:       -71        41
#  comp.  2:       -68        37
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.439      0.30     -71    41
# Comp:  1                Halpha      12.12      0.30     -71    41
# Comp:  2             [SII]6716      3.919      0.29     -68    37
# Comp:  2             [SII]6731      3.206      0.29     -68    37
# Comp:  2              HeII4687      0.000      0.29     -68    37
# Comp:  2               HeI5876      1.274      0.29     -68    37
# Comp:  2          [OIII]5007_d      5.794      0.37     -68    37
# Comp:  2            [OI]6300_d      1.122      0.37     -68    37
# Comp:  2           [NII]6583_d      4.425      0.37     -68    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        31
#  comp.  1:       -72        43
#  comp.  2:       -70        27
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.358      0.30     -72    43
# Comp:  1                Halpha      12.13      0.30     -72    43
# Comp:  2             [SII]6716      3.767      0.29     -70    27
# Comp:  2             [SII]6731      3.257      0.29     -70    27
# Comp:  2              HeII4687     0.1679      0.29     -70    27
# Comp:  2               HeI5876      1.185      0.29     -70    27
# Comp:  2          [OIII]5007_d      5.714      0.36     -70    27
# Comp:  2            [OI]6300_d     0.8706      0.36     -70    27
# Comp:  2           [NII]6583_d      4.029      0.36     -70    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        42
#  comp.  1:       -70        39
#  comp.  2:       -71        32
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.948      0.30     -70    39
# Comp:  1                Halpha      11.93      0.30     -70    39
# Comp:  2             [SII]6716      3.815      0.29     -71    32
# Comp:  2             [SII]6731      2.923      0.29     -71    32
# Comp:  2              HeII4687      0.000      0.29     -71    32
# Comp:  2               HeI5876      1.241      0.29     -71    32
# Comp:  2          [OIII]5007_d      5.575      0.37     -71    32
# Comp:  2            [OI]6300_d      1.073      0.37     -71    32
# Comp:  2           [NII]6583_d      4.380      0.37     -71    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -71        38
#  comp.  2:       -67        31
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.087      0.29     -71    38
# Comp:  1                Halpha      11.93      0.29     -71    38
# Comp:  2             [SII]6716      3.809      0.29     -67    31
# Comp:  2             [SII]6731      3.303      0.29     -67    31
# Comp:  2              HeII4687      0.000      0.29     -67    31
# Comp:  2               HeI5876      1.297      0.29     -67    31
# Comp:  2          [OIII]5007_d      5.638      0.36     -67    31
# Comp:  2            [OI]6300_d      1.457      0.36     -67    31
# Comp:  2           [NII]6583_d      4.320      0.36     -67    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        34
#  comp.  1:       -71        40
#  comp.  2:       -75        45
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.894      0.30     -71    40
# Comp:  1                Halpha      11.97      0.30     -71    40
# Comp:  2             [SII]6716      3.934      0.30     -75    45
# Comp:  2             [SII]6731      3.823      0.30     -75    45
# Comp:  2              HeII4687     0.2127      0.30     -75    45
# Comp:  2               HeI5876      1.531      0.30     -75    45
# Comp:  2          [OIII]5007_d      6.171      0.38     -75    45
# Comp:  2            [OI]6300_d      1.424      0.38     -75    45
# Comp:  2           [NII]6583_d      4.696      0.38     -75    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -71        41
#  comp.  2:       -71        37
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.714      0.30     -71    41
# Comp:  1                Halpha      12.26      0.30     -71    41
# Comp:  2             [SII]6716      3.705      0.29     -71    37
# Comp:  2             [SII]6731      3.445      0.29     -71    37
# Comp:  2              HeII4687     0.1294      0.29     -71    37
# Comp:  2               HeI5876      1.311      0.29     -71    37
# Comp:  2          [OIII]5007_d      5.727      0.37     -71    37
# Comp:  2            [OI]6300_d      1.381      0.37     -71    37
# Comp:  2           [NII]6583_d      4.592      0.37     -71    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        73
#  comp.  1:       -72        45
#  comp.  2:       -77        32
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.856      0.30     -72    45
# Comp:  1                Halpha      12.20      0.30     -72    45
# Comp:  2             [SII]6716      3.787      0.29     -77    32
# Comp:  2             [SII]6731      3.273      0.29     -77    32
# Comp:  2              HeII4687     0.3103      0.29     -77    32
# Comp:  2               HeI5876      1.249      0.29     -77    32
# Comp:  2          [OIII]5007_d      5.783      0.37     -77    32
# Comp:  2            [OI]6300_d      1.459      0.37     -77    32
# Comp:  2           [NII]6583_d      4.545      0.37     -77    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        52
#  comp.  1:       -72        42
#  comp.  2:       -71        50
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.774      0.30     -72    42
# Comp:  1                Halpha      12.51      0.30     -72    42
# Comp:  2             [SII]6716      4.152      0.31     -71    50
# Comp:  2             [SII]6731      3.635      0.31     -71    50
# Comp:  2              HeII4687     0.2702      0.31     -71    50
# Comp:  2               HeI5876      1.390      0.31     -71    50
# Comp:  2          [OIII]5007_d      5.448      0.39     -71    50
# Comp:  2            [OI]6300_d      1.584      0.39     -71    50
# Comp:  2           [NII]6583_d      4.565      0.39     -71    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -71        39
#  comp.  2:       -75        28
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.317      0.30     -71    39
# Comp:  1                Halpha      11.84      0.30     -71    39
# Comp:  2             [SII]6716      3.748      0.29     -75    28
# Comp:  2             [SII]6731      3.465      0.29     -75    28
# Comp:  2              HeII4687     0.2892      0.29     -75    28
# Comp:  2               HeI5876      1.228      0.29     -75    28
# Comp:  2          [OIII]5007_d      6.437      0.36     -75    28
# Comp:  2            [OI]6300_d      1.110      0.36     -75    28
# Comp:  2           [NII]6583_d      4.482      0.36     -75    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -70        43
#  comp.  2:       -74        46
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.616      0.30     -70    43
# Comp:  1                Halpha      12.33      0.30     -70    43
# Comp:  2             [SII]6716      4.064      0.30     -74    46
# Comp:  2             [SII]6731      3.622      0.30     -74    46
# Comp:  2              HeII4687      0.000      0.30     -74    46
# Comp:  2               HeI5876      1.369      0.30     -74    46
# Comp:  2          [OIII]5007_d      6.238      0.38     -74    46
# Comp:  2            [OI]6300_d      1.027      0.38     -74    46
# Comp:  2           [NII]6583_d      4.405      0.38     -74    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        45
#  comp.  1:       -71        38
#  comp.  2:       -74        39
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.313      0.29     -71    38
# Comp:  1                Halpha      11.88      0.29     -71    38
# Comp:  2             [SII]6716      3.869      0.30     -74    39
# Comp:  2             [SII]6731      3.671      0.30     -74    39
# Comp:  2              HeII4687    0.09991      0.30     -74    39
# Comp:  2               HeI5876      1.329      0.30     -74    39
# Comp:  2          [OIII]5007_d      6.842      0.37     -74    39
# Comp:  2            [OI]6300_d      1.109      0.37     -74    39
# Comp:  2           [NII]6583_d      4.507      0.37     -74    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        49
#  comp.  1:       -74        42
#  comp.  2:       -75        40
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.666      0.30     -74    42
# Comp:  1                Halpha      12.12      0.30     -74    42
# Comp:  2             [SII]6716      3.911      0.30     -75    40
# Comp:  2             [SII]6731      3.001      0.30     -75    40
# Comp:  2              HeII4687      0.000      0.30     -75    40
# Comp:  2               HeI5876      1.340      0.30     -75    40
# Comp:  2          [OIII]5007_d      6.918      0.37     -75    40
# Comp:  2            [OI]6300_d      1.353      0.37     -75    40
# Comp:  2           [NII]6583_d      4.557      0.37     -75    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:       -70        40
#  comp.  2:       -71        34
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.576      0.30     -70    40
# Comp:  1                Halpha      12.13      0.30     -70    40
# Comp:  2             [SII]6716      3.600      0.29     -71    34
# Comp:  2             [SII]6731      3.337      0.29     -71    34
# Comp:  2              HeII4687      0.000      0.29     -71    34
# Comp:  2               HeI5876      1.365      0.29     -71    34
# Comp:  2          [OIII]5007_d      5.668      0.37     -71    34
# Comp:  2            [OI]6300_d      1.425      0.37     -71    34
# Comp:  2           [NII]6583_d      4.449      0.37     -71    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        44
#  comp.  1:       -71        41
#  comp.  2:       -74        48
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.336      0.30     -71    41
# Comp:  1                Halpha      12.26      0.30     -71    41
# Comp:  2             [SII]6716      3.962      0.31     -74    48
# Comp:  2             [SII]6731      3.720      0.31     -74    48
# Comp:  2              HeII4687     0.1919      0.31     -74    48
# Comp:  2               HeI5876      1.352      0.31     -74    48
# Comp:  2          [OIII]5007_d      6.425      0.39     -74    48
# Comp:  2            [OI]6300_d      1.067      0.39     -74    48
# Comp:  2           [NII]6583_d      4.177      0.39     -74    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        44
#  comp.  1:       -70        41
#  comp.  2:       -77        40
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.965      0.30     -70    41
# Comp:  1                Halpha      12.64      0.30     -70    41
# Comp:  2             [SII]6716      4.070      0.30     -77    40
# Comp:  2             [SII]6731      3.720      0.30     -77    40
# Comp:  2              HeII4687      0.000      0.30     -77    40
# Comp:  2               HeI5876      1.134      0.30     -77    40
# Comp:  2          [OIII]5007_d      6.704      0.37     -77    40
# Comp:  2            [OI]6300_d      1.284      0.37     -77    40
# Comp:  2           [NII]6583_d      4.486      0.37     -77    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        15
#  comp.  1:       -71        43
#  comp.  2:       -70        45
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.800      0.30     -71    43
# Comp:  1                Halpha      12.36      0.30     -71    43
# Comp:  2             [SII]6716      4.132      0.30     -70    45
# Comp:  2             [SII]6731      3.588      0.30     -70    45
# Comp:  2              HeII4687      0.000      0.30     -70    45
# Comp:  2               HeI5876      1.335      0.30     -70    45
# Comp:  2          [OIII]5007_d      6.114      0.38     -70    45
# Comp:  2            [OI]6300_d      1.226      0.38     -70    45
# Comp:  2           [NII]6583_d      4.728      0.38     -70    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:       -71        37
#  comp.  2:       -74        33
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.886      0.29     -71    37
# Comp:  1                Halpha      11.82      0.29     -71    37
# Comp:  2             [SII]6716      3.805      0.29     -74    33
# Comp:  2             [SII]6731      3.320      0.29     -74    33
# Comp:  2              HeII4687     0.2185      0.29     -74    33
# Comp:  2               HeI5876      1.311      0.29     -74    33
# Comp:  2          [OIII]5007_d      6.608      0.37     -74    33
# Comp:  2            [OI]6300_d      1.150      0.37     -74    33
# Comp:  2           [NII]6583_d      4.424      0.37     -74    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -72        39
#  comp.  2:       -72        36
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.555      0.30     -72    39
# Comp:  1                Halpha      12.08      0.30     -72    39
# Comp:  2             [SII]6716      3.959      0.29     -72    36
# Comp:  2             [SII]6731      2.938      0.29     -72    36
# Comp:  2              HeII4687     0.1776      0.29     -72    36
# Comp:  2               HeI5876      1.387      0.29     -72    36
# Comp:  2          [OIII]5007_d      6.720      0.37     -72    36
# Comp:  2            [OI]6300_d      1.026      0.37     -72    36
# Comp:  2           [NII]6583_d      4.520      0.37     -72    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        35
#  comp.  1:       -69        41
#  comp.  2:       -71        44
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.223      0.30     -69    41
# Comp:  1                Halpha      12.31      0.30     -69    41
# Comp:  2             [SII]6716      4.013      0.30     -71    44
# Comp:  2             [SII]6731      3.407      0.30     -71    44
# Comp:  2              HeII4687      0.000      0.30     -71    44
# Comp:  2               HeI5876      1.199      0.30     -71    44
# Comp:  2          [OIII]5007_d      5.284      0.38     -71    44
# Comp:  2            [OI]6300_d      1.058      0.38     -71    44
# Comp:  2           [NII]6583_d      4.976      0.38     -71    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        49
#  comp.  1:       -70        40
#  comp.  2:       -67        36
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.414      0.30     -70    40
# Comp:  1                Halpha      12.13      0.30     -70    40
# Comp:  2             [SII]6716      3.901      0.29     -67    36
# Comp:  2             [SII]6731      3.204      0.29     -67    36
# Comp:  2              HeII4687     0.3573      0.29     -67    36
# Comp:  2               HeI5876      1.158      0.29     -67    36
# Comp:  2          [OIII]5007_d      4.951      0.37     -67    36
# Comp:  2            [OI]6300_d      1.179      0.37     -67    36
# Comp:  2           [NII]6583_d      4.464      0.37     -67    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -71        42
#  comp.  2:       -77        34
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.190      0.30     -71    42
# Comp:  1                Halpha      12.19      0.30     -71    42
# Comp:  2             [SII]6716      3.888      0.29     -77    34
# Comp:  2             [SII]6731      3.666      0.29     -77    34
# Comp:  2              HeII4687      0.000      0.29     -77    34
# Comp:  2               HeI5876      1.236      0.29     -77    34
# Comp:  2          [OIII]5007_d      6.454      0.37     -77    34
# Comp:  2            [OI]6300_d      1.376      0.37     -77    34
# Comp:  2           [NII]6583_d      4.139      0.37     -77    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:       -71        43
#  comp.  2:       -68        38
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.591      0.30     -71    43
# Comp:  1                Halpha      12.24      0.30     -71    43
# Comp:  2             [SII]6716      3.824      0.29     -68    38
# Comp:  2             [SII]6731      3.200      0.29     -68    38
# Comp:  2              HeII4687      0.000      0.29     -68    38
# Comp:  2               HeI5876      1.467      0.29     -68    38
# Comp:  2          [OIII]5007_d      5.831      0.37     -68    38
# Comp:  2            [OI]6300_d      1.042      0.37     -68    38
# Comp:  2           [NII]6583_d      4.225      0.37     -68    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -71        40
#  comp.  2:       -73        46
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.320      0.30     -71    40
# Comp:  1                Halpha      12.02      0.30     -71    40
# Comp:  2             [SII]6716      3.946      0.30     -73    46
# Comp:  2             [SII]6731      3.433      0.30     -73    46
# Comp:  2              HeII4687      0.000      0.30     -73    46
# Comp:  2               HeI5876      1.570      0.30     -73    46
# Comp:  2          [OIII]5007_d      6.191      0.38     -73    46
# Comp:  2            [OI]6300_d      1.349      0.38     -73    46
# Comp:  2           [NII]6583_d      4.750      0.38     -73    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        41
#  comp.  1:       -71        41
#  comp.  2:       -66        38
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.008      0.30     -71    41
# Comp:  1                Halpha      12.22      0.30     -71    41
# Comp:  2             [SII]6716      3.910      0.29     -66    38
# Comp:  2             [SII]6731      3.093      0.29     -66    38
# Comp:  2              HeII4687      0.000      0.29     -66    38
# Comp:  2               HeI5876      1.287      0.29     -66    38
# Comp:  2          [OIII]5007_d      5.106      0.37     -66    38
# Comp:  2            [OI]6300_d     0.7981      0.37     -66    38
# Comp:  2           [NII]6583_d      4.572      0.37     -66    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        36
#  comp.  1:       -70        44
#  comp.  2:       -73        46
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.278      0.30     -70    44
# Comp:  1                Halpha      12.41      0.30     -70    44
# Comp:  2             [SII]6716      4.123      0.30     -73    46
# Comp:  2             [SII]6731      3.381      0.30     -73    46
# Comp:  2              HeII4687      0.000      0.30     -73    46
# Comp:  2               HeI5876      1.310      0.30     -73    46
# Comp:  2          [OIII]5007_d      6.259      0.38     -73    46
# Comp:  2            [OI]6300_d      1.233      0.38     -73    46
# Comp:  2           [NII]6583_d      5.001      0.38     -73    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        15
#  comp.  1:       -70        42
#  comp.  2:       -67        46
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.118      0.30     -70    42
# Comp:  1                Halpha      12.14      0.30     -70    42
# Comp:  2             [SII]6716      3.882      0.30     -67    46
# Comp:  2             [SII]6731      3.420      0.30     -67    46
# Comp:  2              HeII4687      0.000      0.30     -67    46
# Comp:  2               HeI5876      1.254      0.30     -67    46
# Comp:  2          [OIII]5007_d      5.365      0.38     -67    46
# Comp:  2            [OI]6300_d      1.142      0.38     -67    46
# Comp:  2           [NII]6583_d      4.723      0.38     -67    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        12
#  comp.  1:       -72        41
#  comp.  2:       -70        36
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.335      0.30     -72    41
# Comp:  1                Halpha      12.02      0.30     -72    41
# Comp:  2             [SII]6716      3.754      0.29     -70    36
# Comp:  2             [SII]6731      3.386      0.29     -70    36
# Comp:  2              HeII4687      0.000      0.29     -70    36
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.546      0.30     -70    39
# Comp:  1                Halpha      12.12      0.30     -70    39
# Comp:  2             [SII]6716      3.705      0.29     -76    35
# Comp:  2             [SII]6731      3.597      0.29     -76    35
# Comp:  2              HeII4687     0.1978      0.29     -76    35
# Comp:  2               HeI5876      1.300      0.29     -76    35
# Comp:  2          [OIII]5007_d      6.585      0.37     -76    35
# Comp:  2            [OI]6300_d      1.397      0.37     -76    35
# Comp:  2           [NII]6583_d      4.535      0.37     -76    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        18
#  comp.  1:       -72        41
#  comp.  2:       -67        39
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.292      0.30     -72    41
# Comp:  1                Halpha      12.01      0.30     -72    41
# Comp:  2             [SII]6716      3.858      0.30     -67    39
# Comp:  2             [SII]6731      3.338      0.30     -67    39
# Comp:  2              HeII4687     0.3551      0.30     -67    39
# Comp:  2               HeI5876      1.313      0.30     -67    39
# Comp:  2          [OIII]5007_d      6.005      0.37     -67    39
# Comp:  2            [OI]6300_d      1.343      0.37     -67    39
# Comp:  2           [NII]6583_d      4.684      0.37     -67    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         8
#  comp.  1:       -70        41
#  comp.  2:       -67        35
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.201      0.30     -70    41
# Comp:  1                Halpha      12.34      0.30     -70    41
# Comp:  2             [SII]6716      3.632      0.29     -67    35
# Comp:  2             [SII]6731      3.298      0.29     -67    35
# Comp:  2              HeII4687      0.000      0.29     -67    35
# Comp:  2               HeI5876      1.213      0.29     -67    35
# Comp:  2          [OIII]5007_d      5.975      0.37     -67    35
# Comp:  2            [OI]6300_d      1.310      0.37     -67    35
# Comp:  2           [NII]6583_d      3.977      0.37     -67    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        31
#  comp.  1:       -71        41
#  comp.  2:       -74        36
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.249      0.30     -71    41
# Comp:  1                Halpha      12.07      0.30     -71    41
# Comp:  2             [SII]6716      3.915      0.29     -74    36
# Comp:  2             [SII]6731      3.425      0.29     -74    36
# Comp:  2              HeII4687      0.000      0.29     -74    36
# Comp:  2               HeI5876      1.243      0.29     -74    36
# Comp:  2          [OIII]5007_d      5.911      0.37     -74    36
# Comp:  2            [OI]6300_d      1.361      0.37     -74    36
# Comp:  2           [NII]6583_d      4.476      0.37     -74    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        37
#  comp.  1:       -70        43
#  comp.  2:       -70        37
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.218      0.30     -70    43
# Comp:  1                Halpha      12.45      0.30     -70    43
# Comp:  2             [SII]6716      3.653      0.29     -70    37
# Comp:  2             [SII]6731      3.570      0.29     -70    37
# Comp:  2              HeII4687      0.000      0.29     -70    37
# Comp:  2               HeI5876      1.409      0.29     -70    37
# Comp:  2          [OIII]5007_d      5.813      0.37     -70    37
# Comp:  2            [OI]6300_d      1.240      0.37     -70    37
# Comp:  2           [NII]6583_d      4.215      0.37     -70    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        40
#  comp.  1:       -73        42
#  comp.  2:       -73        41
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.434      0.30     -73    42
# Comp:  1                Halpha      12.17      0.30     -73    42
# Comp:  2             [SII]6716      3.713      0.30     -73    41
# Comp:  2             [SII]6731      3.470      0.30     -73    41
# Comp:  2              HeII4687      0.000      0.30     -73    41
# Comp:  2               HeI5876      1.308      0.30     -73    41
# Comp:  2          [OIII]5007_d      5.236      0.38     -73    41
# Comp:  2            [OI]6300_d     0.9859      0.38     -73    41
# Comp:  2           [NII]6583_d      4.526      0.38     -73    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -70        41
#  comp.  2:       -68        50
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.795      0.30     -70    41
# Comp:  1                Halpha      12.40      0.30     -70    41
# Comp:  2             [SII]6716      3.997      0.31     -68    50
# Comp:  2             [SII]6731      3.591      0.31     -68    50
# Comp:  2              HeII4687      0.000      0.31     -68    50
# Comp:  2               HeI5876      1.437      0.31     -68    50
# Comp:  2          [OIII]5007_d      5.462      0.39     -68    50
# Comp:  2            [OI]6300_d      1.263      0.39     -68    50
# Comp:  2           [NII]6583_d      4.580      0.39     -68    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        85
#  comp.  1:       -72        41
#  comp.  2:       -75        41
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.684      0.30     -72    41
# Comp:  1                Halpha      12.33      0.30     -72    41
# Comp:  2             [SII]6716      3.896      0.30     -75    41
# Comp:  2             [SII]6731      3.305      0.30     -75    41
# Comp:  2              HeII4687      0.000      0.30     -75    41
# Comp:  2               HeI5876      1.190      0.30     -75    41
# Comp:  2          [OIII]5007_d      6.023      0.38     -75    41
# Comp:  2            [OI]6300_d     0.8302      0.38     -75    41
# Comp:  2           [NII]6583_d      4.352      0.38     -75    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        48
#  comp.  1:       -73        41
#  comp.  2:       -68        48
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.145      0.30     -73    41
# Comp:  1                Halpha      11.98      0.30     -73    41
# Comp:  2             [SII]6716      4.016      0.30     -68    48
# Comp:  2             [SII]6731      3.597      0.30     -68    48
# Comp:  2              HeII4687      0.000      0.30     -68    48
# Comp:  2               HeI5876      1.458      0.30     -68    48
# Comp:  2          [OIII]5007_d      5.452      0.38     -68    48
# Comp:  2            [OI]6300_d      1.095      0.38     -68    48
# Comp:  2           [NII]6583_d      4.717      0.38     -68    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -72        40
#  comp.  2:       -70        26
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.175      0.30     -72    40
# Comp:  1                Halpha      12.05      0.30     -72    40
# Comp:  2             [SII]6716      3.767      0.28     -70    26
# Comp:  2             [SII]6731      3.209      0.28     -70    26
# Comp:  2              HeII4687     0.3226      0.28     -70    26
# Comp:  2               HeI5876      1.340      0.28     -70    26
# Comp:  2          [OIII]5007_d      4.820      0.36     -70    26
# Comp:  2            [OI]6300_d      1.158      0.36     -70    26
# Comp:  2           [NII]6583_d      4.113      0.36     -70    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -72        43
#  comp.  2:       -76        33
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.044      0.30     -72    43
# Comp:  1                Halpha      12.11      0.30     -72    43
# Comp:  2             [SII]6716      3.845      0.29     -76    33
# Comp:  2             [SII]6731      3.205      0.29     -76    33
# Comp:  2              HeII4687      0.000      0.29     -76    33
# Comp:  2               HeI5876      1.311      0.29     -76    33
# Comp:  2          [OIII]5007_d      6.597      0.37     -76    33
# Comp:  2            [OI]6300_d      1.045      0.37     -76    33
# Comp:  2           [NII]6583_d      4.282      0.37     -76    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -72        40
#  comp.  2:       -68        38
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.739      0.30     -72    40
# Comp:  1                Halpha      12.04      0.30     -72    40
# Comp:  2             [SII]6716      3.642      0.29     -68    38
# Comp:  2             [SII]6731      3.257      0.29     -68    38
# Comp:  2              HeII4687      0.000      0.29     -68    38
# Comp:  2               HeI5876      1.456      0.29     -68    38
# Comp:  2          [OIII]5007_d      5.895      0.37     -68    38
# Comp:  2            [OI]6300_d      1.058      0.37     -68    38
# Comp:  2           [NII]6583_d      4.677      0.37     -68    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        46
#  comp.  1:       -71        42
#  comp.  2:       -69        45
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.177      0.30     -71    42
# Comp:  1                Halpha      11.92      0.30     -71    42
# Comp:  2             [SII]6716      3.965      0.30     -69    45
# Comp:  2             [SII]6731      3.649      0.30     -69    45
# Comp:  2              HeII4687     0.1670      0.30     -69    45
# Comp:  2               HeI5876      1.476      0.30     -69    45
# Comp:  2          [OIII]5007_d      5.241      0.38     -69    45
# Comp:  2            [OI]6300_d      1.491      0.38     -69    45
# Comp:  2           [NII]6583_d      4.761      0.38     -69    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        35
#  comp.  1:       -72        41
#  comp.  2:       -73        34
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.508      0.30     -72    41
# Comp:  1                Halpha      12.05      0.30     -72    41
# Comp:  2             [SII]6716      3.902      0.29     -73    34
# Comp:  2             [SII]6731      3.212      0.29     -73    34
# Comp:  2              HeII4687      0.000      0.29     -73    34
# Comp:  2               HeI5876      1.279      0.29     -73    34
# Comp:  2          [OIII]5007_d      5.975      0.37     -73    34
# Comp:  2            [OI]6300_d      1.498      0.37     -73    34
# Comp:  2           [NII]6583_d      4.328      0.37     -73    34
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.39425123, 0.31262901, 0.19458094, 0.31128338, 0.12489451,
#        0.11474106, 0.61756458, 0.27855302, 0.32842678])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.35468561, 16.4781795 ,  5.42025095,  4.71169549,  0.        ,
#         1.59852201,  6.21165455,  1.54494022,  6.1594578 ])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_2_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_2", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_2_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_2_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_2_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.096538    0.011345
# 1        Halpha  0.474193    0.008997
# 2     [SII]6716  0.155979    0.005599
# 3     [SII]6731  0.135588    0.008958
# 4      HeII4687  0.000000    0.003594
# 5       HeI5876  0.046001    0.003302
# 6  [OIII]5007_d  0.178753    0.017772
# 7    [OI]6300_d  0.044459    0.008016
# 8   [NII]6583_d  0.177251    0.009451
#           Name      Flux  Error_flux
# 0        Hbeta  0.096538    0.011345
# 1       Halpha  0.474193    0.008997
# 2    [SII]6716  0.155979    0.005599
# 3    [SII]6731  0.135588    0.008958
# 4     HeII4687  0.000000    0.003594
# 5      HeI5876  0.046001    0.003302
# 6   [OIII]4959  0.044688    0.017772
# 7   [OIII]5007  0.134065    0.017772
# 8     [OI]6300  0.033344    0.008016
# 9     [OI]6364  0.011115    0.008016
# 10   [NII]6548  0.044313    0.009451
# 11   [NII]6583  0.132938    0.009451

# %%
np.median(flux_rf_rebin)
# Out:
# 0.02877700426873525
