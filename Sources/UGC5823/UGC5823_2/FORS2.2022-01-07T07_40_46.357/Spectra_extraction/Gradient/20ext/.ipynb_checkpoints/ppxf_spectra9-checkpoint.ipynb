# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_9.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_9']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.03945653 0.03078233 0.02557937 ... 0.02547623 0.03087098 0.02695033] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        50
# chi2/DOF: 0.02481; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        49
# chi2/DOF: 0.01612; DOF: 1917; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-38.48341076,  48.67791778])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        39
#  comp.  1:       -72        51
#  comp.  2:       -82        42
# chi2/DOF: 1.056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.093      0.33     -72    51
# Comp:  1                Halpha      4.664      0.33     -72    51
# Comp:  2             [SII]6716      2.757      0.32     -82    42
# Comp:  2             [SII]6731      1.317      0.32     -82    42
# Comp:  2              HeII4687     0.3789      0.32     -82    42
# Comp:  2               HeI5876     0.5871      0.32     -82    42
# Comp:  2          [OIII]5007_d      1.500      0.40     -82    42
# Comp:  2            [OI]6300_d     0.5775      0.40     -82    42
# Comp:  2           [NII]6583_d      1.863      0.40     -82    42
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  2.341; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  10.35; gas flux:      6 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  6.696; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   3.09; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.9201; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   1.42; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.679; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.9962; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.365; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        38
#  comp.  1:       -78        54
#  comp.  2:       -93        43
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7283      0.33     -78    54
# Comp:  1                Halpha      4.552      0.33     -78    54
# Comp:  2             [SII]6716      2.690      0.32     -93    43
# Comp:  2             [SII]6731      1.217      0.32     -93    43
# Comp:  2              HeII4687     0.2041      0.32     -93    43
# Comp:  2               HeI5876     0.7286      0.32     -93    43
# Comp:  2          [OIII]5007_d      1.215      0.40     -93    43
# Comp:  2            [OI]6300_d     0.3501      0.40     -93    43
# Comp:  2           [NII]6583_d      2.045      0.40     -93    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        42
#  comp.  1:       -78        58
#  comp.  2:       -87        34
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8548      0.34     -78    58
# Comp:  1                Halpha      4.842      0.34     -78    58
# Comp:  2             [SII]6716      2.689      0.31     -87    34
# Comp:  2             [SII]6731      1.195      0.31     -87    34
# Comp:  2              HeII4687     0.5238      0.31     -87    34
# Comp:  2               HeI5876     0.4661      0.31     -87    34
# Comp:  2          [OIII]5007_d     0.8544      0.39     -87    34
# Comp:  2            [OI]6300_d     0.5887      0.39     -87    34
# Comp:  2           [NII]6583_d      1.837      0.39     -87    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        98
#  comp.  1:       -67        55
#  comp.  2:       -79        39
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.944      0.33     -67    55
# Comp:  1                Halpha      5.225      0.33     -67    55
# Comp:  2             [SII]6716      2.725      0.31     -79    39
# Comp:  2             [SII]6731      1.282      0.31     -79    39
# Comp:  2              HeII4687      0.000      0.31     -79    39
# Comp:  2               HeI5876     0.6628      0.31     -79    39
# Comp:  2          [OIII]5007_d      1.209      0.40     -79    39
# Comp:  2            [OI]6300_d     0.3256      0.40     -79    39
# Comp:  2           [NII]6583_d      1.856      0.40     -79    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        64
#  comp.  1:       -76        48
#  comp.  2:       -83        37
# chi2/DOF: 1.050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8275      0.32     -76    48
# Comp:  1                Halpha      4.557      0.32     -76    48
# Comp:  2             [SII]6716      2.648      0.31     -83    37
# Comp:  2             [SII]6731      1.229      0.31     -83    37
# Comp:  2              HeII4687     0.6824      0.31     -83    37
# Comp:  2               HeI5876     0.4455      0.31     -83    37
# Comp:  2          [OIII]5007_d      1.227      0.39     -83    37
# Comp:  2            [OI]6300_d     0.5941      0.39     -83    37
# Comp:  2           [NII]6583_d      2.004      0.39     -83    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -79        54
#  comp.  2:       -80        33
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.618      0.33     -79    54
# Comp:  1                Halpha      4.877      0.33     -79    54
# Comp:  2             [SII]6716      2.833      0.31     -80    33
# Comp:  2             [SII]6731      1.346      0.31     -80    33
# Comp:  2              HeII4687     0.4040      0.31     -80    33
# Comp:  2               HeI5876     0.6557      0.31     -80    33
# Comp:  2          [OIII]5007_d      1.592      0.39     -80    33
# Comp:  2            [OI]6300_d     0.4438      0.39     -80    33
# Comp:  2           [NII]6583_d      1.502      0.39     -80    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -72        51
#  comp.  2:       -84        59
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.588      0.33     -72    51
# Comp:  1                Halpha      4.677      0.33     -72    51
# Comp:  2             [SII]6716      2.997      0.34     -84    59
# Comp:  2             [SII]6731      1.443      0.34     -84    59
# Comp:  2              HeII4687     0.4001      0.34     -84    59
# Comp:  2               HeI5876     0.6064      0.34     -84    59
# Comp:  2          [OIII]5007_d      1.707      0.43     -84    59
# Comp:  2            [OI]6300_d     0.3147      0.43     -84    59
# Comp:  2           [NII]6583_d      1.858      0.43     -84    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -73        40
#  comp.  2:       -84        25
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.105      0.31     -73    40
# Comp:  1                Halpha      4.510      0.31     -73    40
# Comp:  2             [SII]6716      2.490      0.30     -84    25
# Comp:  2             [SII]6731      1.093      0.30     -84    25
# Comp:  2              HeII4687     0.6934      0.30     -84    25
# Comp:  2               HeI5876     0.6304      0.30     -84    25
# Comp:  2          [OIII]5007_d      1.730      0.38     -84    25
# Comp:  2            [OI]6300_d     0.3291      0.38     -84    25
# Comp:  2           [NII]6583_d      1.876      0.38     -84    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        63
#  comp.  1:       -75        54
#  comp.  2:       -78        20
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.376      0.33     -75    54
# Comp:  1                Halpha      4.804      0.33     -75    54
# Comp:  2             [SII]6716      2.296      0.30     -78    20
# Comp:  2             [SII]6731      1.041      0.30     -78    20
# Comp:  2              HeII4687    0.05024      0.30     -78    20
# Comp:  2               HeI5876     0.5059      0.30     -78    20
# Comp:  2          [OIII]5007_d      1.054      0.38     -78    20
# Comp:  2            [OI]6300_d     0.6027      0.38     -78    20
# Comp:  2           [NII]6583_d      1.884      0.38     -78    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        28
#  comp.  1:       -73        44
#  comp.  2:       -87        47
# chi2/DOF: 1.050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8342      0.32     -73    44
# Comp:  1                Halpha      4.588      0.32     -73    44
# Comp:  2             [SII]6716      2.827      0.32     -87    47
# Comp:  2             [SII]6731      1.319      0.32     -87    47
# Comp:  2              HeII4687     0.2445      0.32     -87    47
# Comp:  2               HeI5876     0.6231      0.32     -87    47
# Comp:  2          [OIII]5007_d      1.916      0.41     -87    47
# Comp:  2            [OI]6300_d     0.5866      0.41     -87    47
# Comp:  2           [NII]6583_d      1.847      0.41     -87    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -68        48
#  comp.  2:       -74        59
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.251      0.32     -68    48
# Comp:  1                Halpha      4.724      0.32     -68    48
# Comp:  2             [SII]6716      2.954      0.34     -74    59
# Comp:  2             [SII]6731      1.406      0.34     -74    59
# Comp:  2              HeII4687     0.5894      0.34     -74    59
# Comp:  2               HeI5876     0.5744      0.34     -74    59
# Comp:  2          [OIII]5007_d     0.8881      0.42     -74    59
# Comp:  2            [OI]6300_d     0.7741      0.42     -74    59
# Comp:  2           [NII]6583_d      2.057      0.42     -74    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        28
#  comp.  1:       -71        51
#  comp.  2:       -86        31
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.419      0.33     -71    51
# Comp:  1                Halpha      4.827      0.33     -71    51
# Comp:  2             [SII]6716      2.549      0.31     -86    31
# Comp:  2             [SII]6731      1.057      0.31     -86    31
# Comp:  2              HeII4687     0.1272      0.31     -86    31
# Comp:  2               HeI5876     0.4359      0.31     -86    31
# Comp:  2          [OIII]5007_d      1.695      0.39     -86    31
# Comp:  2            [OI]6300_d     0.3253      0.39     -86    31
# Comp:  2           [NII]6583_d      1.719      0.39     -86    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        76
#  comp.  1:       -79        57
#  comp.  2:       -74        44
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8199      0.33     -79    57
# Comp:  1                Halpha      4.505      0.33     -79    57
# Comp:  2             [SII]6716      2.790      0.32     -74    44
# Comp:  2             [SII]6731      1.260      0.32     -74    44
# Comp:  2              HeII4687     0.4946      0.32     -74    44
# Comp:  2               HeI5876     0.4553      0.32     -74    44
# Comp:  2          [OIII]5007_d      1.040      0.40     -74    44
# Comp:  2            [OI]6300_d     0.5907      0.40     -74    44
# Comp:  2           [NII]6583_d      1.762      0.40     -74    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        22
#  comp.  1:       -75        46
#  comp.  2:       -79        43
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.482      0.32     -75    46
# Comp:  1                Halpha      4.716      0.32     -75    46
# Comp:  2             [SII]6716      2.947      0.32     -79    43
# Comp:  2             [SII]6731      1.350      0.32     -79    43
# Comp:  2              HeII4687     0.1703      0.32     -79    43
# Comp:  2               HeI5876     0.6871      0.32     -79    43
# Comp:  2          [OIII]5007_d      2.002      0.40     -79    43
# Comp:  2            [OI]6300_d     0.3997      0.40     -79    43
# Comp:  2           [NII]6583_d      1.762      0.40     -79    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        43
#  comp.  1:       -78        60
#  comp.  2:       -82        27
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.431      0.34     -78    60
# Comp:  1                Halpha      5.007      0.34     -78    60
# Comp:  2             [SII]6716      2.748      0.30     -82    27
# Comp:  2             [SII]6731      1.428      0.30     -82    27
# Comp:  2              HeII4687     0.3488      0.30     -82    27
# Comp:  2               HeI5876     0.4940      0.30     -82    27
# Comp:  2          [OIII]5007_d      1.985      0.38     -82    27
# Comp:  2            [OI]6300_d     0.3067      0.38     -82    27
# Comp:  2           [NII]6583_d      1.793      0.38     -82    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -70        47
#  comp.  2:       -78        17
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7555      0.32     -70    47
# Comp:  1                Halpha      4.598      0.32     -70    47
# Comp:  2             [SII]6716      2.517      0.30     -78    17
# Comp:  2             [SII]6731      1.225      0.30     -78    17
# Comp:  2              HeII4687     0.6636      0.30     -78    17
# Comp:  2               HeI5876     0.5444      0.30     -78    17
# Comp:  2          [OIII]5007_d      1.623      0.37     -78    17
# Comp:  2            [OI]6300_d     0.2267      0.37     -78    17
# Comp:  2           [NII]6583_d      1.737      0.37     -78    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        38
#  comp.  1:       -76        49
#  comp.  2:       -77        60
# chi2/DOF: 1.050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.173      0.32     -76    49
# Comp:  1                Halpha      4.616      0.32     -76    49
# Comp:  2             [SII]6716      3.178      0.34     -77    60
# Comp:  2             [SII]6731      1.536      0.34     -77    60
# Comp:  2              HeII4687      0.000      0.34     -77    60
# Comp:  2               HeI5876     0.5199      0.34     -77    60
# Comp:  2          [OIII]5007_d      1.542      0.43     -77    60
# Comp:  2            [OI]6300_d     0.3201      0.43     -77    60
# Comp:  2           [NII]6583_d      1.872      0.43     -77    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         8
#  comp.  1:       -79        56
#  comp.  2:       -84        28
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9904      0.33     -79    56
# Comp:  1                Halpha      4.832      0.33     -79    56
# Comp:  2             [SII]6716      2.519      0.30     -84    28
# Comp:  2             [SII]6731      1.180      0.30     -84    28
# Comp:  2              HeII4687     0.2563      0.30     -84    28
# Comp:  2               HeI5876     0.4822      0.30     -84    28
# Comp:  2          [OIII]5007_d      1.879      0.38     -84    28
# Comp:  2            [OI]6300_d     0.2864      0.38     -84    28
# Comp:  2           [NII]6583_d      1.737      0.38     -84    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        63
#  comp.  1:       -66        53
#  comp.  2:       -77        51
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.273      0.33     -66    53
# Comp:  1                Halpha      4.873      0.33     -66    53
# Comp:  2             [SII]6716      2.850      0.33     -77    51
# Comp:  2             [SII]6731      1.367      0.33     -77    51
# Comp:  2              HeII4687     0.6729      0.33     -77    51
# Comp:  2               HeI5876     0.6301      0.33     -77    51
# Comp:  2          [OIII]5007_d      1.561      0.41     -77    51
# Comp:  2            [OI]6300_d     0.6446      0.41     -77    51
# Comp:  2           [NII]6583_d      2.024      0.41     -77    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        68
#  comp.  1:       -71        57
#  comp.  2:       -82        16
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.019      0.33     -71    57
# Comp:  1                Halpha      4.829      0.33     -71    57
# Comp:  2             [SII]6716      2.483      0.29     -82    16
# Comp:  2             [SII]6731      1.250      0.29     -82    16
# Comp:  2              HeII4687     0.4483      0.29     -82    16
# Comp:  2               HeI5876     0.5601      0.29     -82    16
# Comp:  2          [OIII]5007_d      1.736      0.37     -82    16
# Comp:  2            [OI]6300_d     0.6412      0.37     -82    16
# Comp:  2           [NII]6583_d      1.882      0.37     -82    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        56
#  comp.  1:       -74        58
#  comp.  2:       -84        46
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.151      0.34     -74    58
# Comp:  1                Halpha      4.732      0.34     -74    58
# Comp:  2             [SII]6716      2.858      0.32     -84    46
# Comp:  2             [SII]6731      1.459      0.32     -84    46
# Comp:  2              HeII4687     0.8311      0.32     -84    46
# Comp:  2               HeI5876     0.6602      0.32     -84    46
# Comp:  2          [OIII]5007_d      1.077      0.40     -84    46
# Comp:  2            [OI]6300_d     0.7273      0.40     -84    46
# Comp:  2           [NII]6583_d      2.036      0.40     -84    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        61
#  comp.  1:       -82        53
#  comp.  2:       -79        41
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.272      0.33     -82    53
# Comp:  1                Halpha      4.748      0.33     -82    53
# Comp:  2             [SII]6716      2.532      0.31     -79    41
# Comp:  2             [SII]6731      1.201      0.31     -79    41
# Comp:  2              HeII4687     0.1143      0.31     -79    41
# Comp:  2               HeI5876     0.4978      0.31     -79    41
# Comp:  2          [OIII]5007_d      1.532      0.40     -79    41
# Comp:  2            [OI]6300_d     0.6836      0.40     -79    41
# Comp:  2           [NII]6583_d      2.175      0.40     -79    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        88
#  comp.  1:       -77        53
#  comp.  2:       -91        42
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8555      0.33     -77    53
# Comp:  1                Halpha      4.642      0.33     -77    53
# Comp:  2             [SII]6716      2.792      0.32     -91    42
# Comp:  2             [SII]6731      1.287      0.32     -91    42
# Comp:  2              HeII4687     0.7083      0.32     -91    42
# Comp:  2               HeI5876     0.5729      0.32     -91    42
# Comp:  2          [OIII]5007_d     0.9215      0.40     -91    42
# Comp:  2            [OI]6300_d     0.7702      0.40     -91    42
# Comp:  2           [NII]6583_d      1.888      0.40     -91    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -69        52
#  comp.  2:       -76        57
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.288      0.33     -69    52
# Comp:  1                Halpha      4.405      0.33     -69    52
# Comp:  2             [SII]6716      2.974      0.33     -76    57
# Comp:  2             [SII]6731      1.469      0.33     -76    57
# Comp:  2              HeII4687     0.8737      0.33     -76    57
# Comp:  2               HeI5876     0.6403      0.33     -76    57
# Comp:  2          [OIII]5007_d      1.239      0.42     -76    57
# Comp:  2            [OI]6300_d      1.097      0.42     -76    57
# Comp:  2           [NII]6583_d      1.820      0.42     -76    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        79
#  comp.  1:       -74        53
#  comp.  2:       -82        58
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.124      0.33     -74    53
# Comp:  1                Halpha      4.595      0.33     -74    53
# Comp:  2             [SII]6716      2.883      0.34     -82    58
# Comp:  2             [SII]6731      1.403      0.34     -82    58
# Comp:  2              HeII4687     0.2402      0.34     -82    58
# Comp:  2               HeI5876     0.5340      0.34     -82    58
# Comp:  2          [OIII]5007_d      1.673      0.42     -82    58
# Comp:  2            [OI]6300_d     0.3051      0.42     -82    58
# Comp:  2           [NII]6583_d      2.096      0.42     -82    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -72        46
#  comp.  2:       -90        37
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.162      0.32     -72    46
# Comp:  1                Halpha      4.751      0.32     -72    46
# Comp:  2             [SII]6716      2.639      0.31     -90    37
# Comp:  2             [SII]6731      1.568      0.31     -90    37
# Comp:  2              HeII4687      0.000      0.31     -90    37
# Comp:  2               HeI5876     0.6928      0.31     -90    37
# Comp:  2          [OIII]5007_d      1.358      0.39     -90    37
# Comp:  2            [OI]6300_d     0.5413      0.39     -90    37
# Comp:  2           [NII]6583_d      1.563      0.39     -90    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        36
#  comp.  1:       -72        45
#  comp.  2:       -81        27
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.369      0.32     -72    45
# Comp:  1                Halpha      4.535      0.32     -72    45
# Comp:  2             [SII]6716      2.646      0.30     -81    27
# Comp:  2             [SII]6731      1.312      0.30     -81    27
# Comp:  2              HeII4687     0.3769      0.30     -81    27
# Comp:  2               HeI5876     0.4925      0.30     -81    27
# Comp:  2          [OIII]5007_d      1.561      0.38     -81    27
# Comp:  2            [OI]6300_d     0.3960      0.38     -81    27
# Comp:  2           [NII]6583_d      1.784      0.38     -81    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        28
#  comp.  1:       -73        57
#  comp.  2:       -76        36
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.456      0.33     -73    57
# Comp:  1                Halpha      4.720      0.33     -73    57
# Comp:  2             [SII]6716      2.629      0.31     -76    36
# Comp:  2             [SII]6731      1.251      0.31     -76    36
# Comp:  2              HeII4687     0.1387      0.31     -76    36
# Comp:  2               HeI5876     0.6273      0.31     -76    36
# Comp:  2          [OIII]5007_d      1.838      0.39     -76    36
# Comp:  2            [OI]6300_d     0.6034      0.39     -76    36
# Comp:  2           [NII]6583_d      2.043      0.39     -76    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        21
#  comp.  1:       -70        42
#  comp.  2:       -85        47
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.488      0.32     -70    42
# Comp:  1                Halpha      4.638      0.32     -70    42
# Comp:  2             [SII]6716      2.726      0.32     -85    47
# Comp:  2             [SII]6731      1.360      0.32     -85    47
# Comp:  2              HeII4687     0.5920      0.32     -85    47
# Comp:  2               HeI5876     0.7859      0.32     -85    47
# Comp:  2          [OIII]5007_d      1.851      0.41     -85    47
# Comp:  2            [OI]6300_d     0.7669      0.41     -85    47
# Comp:  2           [NII]6583_d      2.086      0.41     -85    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        38
#  comp.  1:       -72        49
#  comp.  2:       -81        35
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.272      0.32     -72    49
# Comp:  1                Halpha      4.773      0.32     -72    49
# Comp:  2             [SII]6716      2.678      0.31     -81    35
# Comp:  2             [SII]6731      1.386      0.31     -81    35
# Comp:  2              HeII4687     0.6276      0.31     -81    35
# Comp:  2               HeI5876     0.5272      0.31     -81    35
# Comp:  2          [OIII]5007_d      1.544      0.39     -81    35
# Comp:  2            [OI]6300_d     0.5293      0.39     -81    35
# Comp:  2           [NII]6583_d      1.610      0.39     -81    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        34
#  comp.  1:       -70        48
#  comp.  2:       -68        60
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.114      0.32     -70    48
# Comp:  1                Halpha      4.975      0.32     -70    48
# Comp:  2             [SII]6716      3.144      0.34     -68    60
# Comp:  2             [SII]6731      1.615      0.34     -68    60
# Comp:  2              HeII4687     0.2420      0.34     -68    60
# Comp:  2               HeI5876     0.5212      0.34     -68    60
# Comp:  2          [OIII]5007_d      2.064      0.43     -68    60
# Comp:  2            [OI]6300_d     0.8119      0.43     -68    60
# Comp:  2           [NII]6583_d      2.155      0.43     -68    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        23
#  comp.  1:       -73        50
#  comp.  2:       -77        29
# chi2/DOF: 1.051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6344      0.33     -73    50
# Comp:  1                Halpha      4.639      0.33     -73    50
# Comp:  2             [SII]6716      2.704      0.30     -77    29
# Comp:  2             [SII]6731      1.213      0.30     -77    29
# Comp:  2              HeII4687     0.5740      0.30     -77    29
# Comp:  2               HeI5876     0.5242      0.30     -77    29
# Comp:  2          [OIII]5007_d      1.746      0.38     -77    29
# Comp:  2            [OI]6300_d     0.4813      0.38     -77    29
# Comp:  2           [NII]6583_d      2.000      0.38     -77    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        68
#  comp.  1:       -72        54
#  comp.  2:       -82        25
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.622      0.33     -72    54
# Comp:  1                Halpha      5.247      0.33     -72    54
# Comp:  2             [SII]6716      2.687      0.30     -82    25
# Comp:  2             [SII]6731      1.140      0.30     -82    25
# Comp:  2              HeII4687     0.7751      0.30     -82    25
# Comp:  2               HeI5876     0.5793      0.30     -82    25
# Comp:  2          [OIII]5007_d      1.867      0.38     -82    25
# Comp:  2            [OI]6300_d     0.6345      0.38     -82    25
# Comp:  2           [NII]6583_d      2.050      0.38     -82    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        89
#  comp.  1:       -76        48
#  comp.  2:       -84        30
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6935      0.32     -76    48
# Comp:  1                Halpha      4.396      0.32     -76    48
# Comp:  2             [SII]6716      2.736      0.30     -84    30
# Comp:  2             [SII]6731      1.259      0.30     -84    30
# Comp:  2              HeII4687     0.6884      0.30     -84    30
# Comp:  2               HeI5876     0.6259      0.30     -84    30
# Comp:  2          [OIII]5007_d      1.847      0.38     -84    30
# Comp:  2            [OI]6300_d     0.3829      0.38     -84    30
# Comp:  2           [NII]6583_d      1.607      0.38     -84    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        15
#  comp.  1:       -63        51
#  comp.  2:       -88        35
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.569      0.33     -63    51
# Comp:  1                Halpha      5.101      0.33     -63    51
# Comp:  2             [SII]6716      2.571      0.31     -88    35
# Comp:  2             [SII]6731      1.323      0.31     -88    35
# Comp:  2              HeII4687     0.5235      0.31     -88    35
# Comp:  2               HeI5876     0.5097      0.31     -88    35
# Comp:  2          [OIII]5007_d      1.149      0.39     -88    35
# Comp:  2            [OI]6300_d     0.5475      0.39     -88    35
# Comp:  2           [NII]6583_d      2.013      0.39     -88    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        42
#  comp.  1:       -69        50
#  comp.  2:       -69        47
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.269      0.33     -69    50
# Comp:  1                Halpha      4.740      0.33     -69    50
# Comp:  2             [SII]6716      2.943      0.32     -69    47
# Comp:  2             [SII]6731      1.394      0.32     -69    47
# Comp:  2              HeII4687    0.08124      0.32     -69    47
# Comp:  2               HeI5876     0.4970      0.32     -69    47
# Comp:  2          [OIII]5007_d      1.111      0.41     -69    47
# Comp:  2            [OI]6300_d     0.6447      0.41     -69    47
# Comp:  2           [NII]6583_d      1.711      0.41     -69    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -71        56
#  comp.  2:       -92        37
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8844      0.33     -71    56
# Comp:  1                Halpha      4.875      0.33     -71    56
# Comp:  2             [SII]6716      2.576      0.31     -92    37
# Comp:  2             [SII]6731      1.387      0.31     -92    37
# Comp:  2              HeII4687     0.1266      0.31     -92    37
# Comp:  2               HeI5876     0.6744      0.31     -92    37
# Comp:  2          [OIII]5007_d      1.738      0.39     -92    37
# Comp:  2            [OI]6300_d     0.5125      0.39     -92    37
# Comp:  2           [NII]6583_d      1.633      0.39     -92    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        48
#  comp.  1:       -71        62
#  comp.  2:       -82        58
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.361      0.34     -71    62
# Comp:  1                Halpha      4.839      0.34     -71    62
# Comp:  2             [SII]6716      3.186      0.33     -82    58
# Comp:  2             [SII]6731      1.527      0.33     -82    58
# Comp:  2              HeII4687     0.2450      0.33     -82    58
# Comp:  2               HeI5876     0.8561      0.33     -82    58
# Comp:  2          [OIII]5007_d      1.615      0.42     -82    58
# Comp:  2            [OI]6300_d     0.5925      0.42     -82    58
# Comp:  2           [NII]6583_d      1.863      0.42     -82    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        79
#  comp.  1:       -75        56
#  comp.  2:       -91        45
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.171      0.33     -75    56
# Comp:  1                Halpha      4.851      0.33     -75    56
# Comp:  2             [SII]6716      2.812      0.32     -91    45
# Comp:  2             [SII]6731      1.524      0.32     -91    45
# Comp:  2              HeII4687      0.000      0.32     -91    45
# Comp:  2               HeI5876     0.6993      0.32     -91    45
# Comp:  2          [OIII]5007_d      1.107      0.40     -91    45
# Comp:  2            [OI]6300_d     0.6539      0.40     -91    45
# Comp:  2           [NII]6583_d      1.743      0.40     -91    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        65
#  comp.  1:       -72        57
#  comp.  2:       -86        61
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.517      0.33     -72    57
# Comp:  1                Halpha      5.101      0.33     -72    57
# Comp:  2             [SII]6716      3.032      0.34     -86    61
# Comp:  2             [SII]6731      1.291      0.34     -86    61
# Comp:  2              HeII4687     0.5849      0.34     -86    61
# Comp:  2               HeI5876     0.7732      0.34     -86    61
# Comp:  2          [OIII]5007_d      1.358      0.43     -86    61
# Comp:  2            [OI]6300_d     0.2581      0.43     -86    61
# Comp:  2           [NII]6583_d      2.042      0.43     -86    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        57
#  comp.  1:       -70        53
#  comp.  2:       -80        42
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.586      0.33     -70    53
# Comp:  1                Halpha      4.994      0.33     -70    53
# Comp:  2             [SII]6716      2.904      0.32     -80    42
# Comp:  2             [SII]6731      1.382      0.32     -80    42
# Comp:  2              HeII4687     0.4500      0.32     -80    42
# Comp:  2               HeI5876     0.4715      0.32     -80    42
# Comp:  2          [OIII]5007_d      1.218      0.40     -80    42
# Comp:  2            [OI]6300_d     0.7335      0.40     -80    42
# Comp:  2           [NII]6583_d      1.974      0.40     -80    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        28
#  comp.  1:       -74        54
#  comp.  2:       -84        42
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.412      0.33     -74    54
# Comp:  1                Halpha      4.908      0.33     -74    54
# Comp:  2             [SII]6716      2.703      0.32     -84    42
# Comp:  2             [SII]6731      1.440      0.32     -84    42
# Comp:  2              HeII4687     0.2357      0.32     -84    42
# Comp:  2               HeI5876     0.4851      0.32     -84    42
# Comp:  2          [OIII]5007_d      1.057      0.40     -84    42
# Comp:  2            [OI]6300_d     0.3762      0.40     -84    42
# Comp:  2           [NII]6583_d      1.929      0.40     -84    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        71
#  comp.  1:       -75        52
#  comp.  2:       -74        46
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.484      0.33     -75    52
# Comp:  1                Halpha      4.826      0.33     -75    52
# Comp:  2             [SII]6716      2.991      0.32     -74    46
# Comp:  2             [SII]6731      1.393      0.32     -74    46
# Comp:  2              HeII4687     0.4431      0.32     -74    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.454      0.33     -69    56
# Comp:  1                Halpha      4.880      0.33     -69    56
# Comp:  2             [SII]6716      2.895      0.33     -85    51
# Comp:  2             [SII]6731      1.640      0.33     -85    51
# Comp:  2              HeII4687     0.6057      0.33     -85    51
# Comp:  2               HeI5876     0.7273      0.33     -85    51
# Comp:  2          [OIII]5007_d      1.734      0.41     -85    51
# Comp:  2            [OI]6300_d     0.7603      0.41     -85    51
# Comp:  2           [NII]6583_d      1.911      0.41     -85    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -70        50
#  comp.  2:       -79        33
# chi2/DOF: 1.051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9757      0.33     -70    50
# Comp:  1                Halpha      4.810      0.33     -70    50
# Comp:  2             [SII]6716      2.682      0.31     -79    33
# Comp:  2             [SII]6731      1.200      0.31     -79    33
# Comp:  2              HeII4687     0.1375      0.31     -79    33
# Comp:  2               HeI5876     0.5568      0.31     -79    33
# Comp:  2          [OIII]5007_d      1.563      0.39     -79    33
# Comp:  2            [OI]6300_d     0.7207      0.39     -79    33
# Comp:  2           [NII]6583_d      1.813      0.39     -79    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         9
#  comp.  1:       -67        47
#  comp.  2:       -83        36
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9242      0.32     -67    47
# Comp:  1                Halpha      4.867      0.32     -67    47
# Comp:  2             [SII]6716      2.658      0.31     -83    36
# Comp:  2             [SII]6731      1.342      0.31     -83    36
# Comp:  2              HeII4687     0.4357      0.31     -83    36
# Comp:  2               HeI5876     0.4958      0.31     -83    36
# Comp:  2          [OIII]5007_d      1.712      0.39     -83    36
# Comp:  2            [OI]6300_d     0.8643      0.39     -83    36
# Comp:  2           [NII]6583_d      1.630      0.39     -83    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -71        51
#  comp.  2:       -81        54
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9718      0.33     -71    51
# Comp:  1                Halpha      4.689      0.33     -71    51
# Comp:  2             [SII]6716      3.088      0.33     -81    54
# Comp:  2             [SII]6731      1.317      0.33     -81    54
# Comp:  2              HeII4687     0.2390      0.33     -81    54
# Comp:  2               HeI5876     0.5800      0.33     -81    54
# Comp:  2          [OIII]5007_d      1.598      0.42     -81    54
# Comp:  2            [OI]6300_d     0.7838      0.42     -81    54
# Comp:  2           [NII]6583_d      2.185      0.42     -81    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        53
#  comp.  1:       -73        40
#  comp.  2:       -79        11
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.029      0.31     -73    40
# Comp:  1                Halpha      4.181      0.31     -73    40
# Comp:  2             [SII]6716      2.295      0.29     -79    11
# Comp:  2             [SII]6731      1.124      0.29     -79    11
# Comp:  2              HeII4687     0.4834      0.29     -79    11
# Comp:  2               HeI5876     0.6270      0.29     -79    11
# Comp:  2          [OIII]5007_d      1.630      0.37     -79    11
# Comp:  2            [OI]6300_d     0.4610      0.37     -79    11
# Comp:  2           [NII]6583_d      1.539      0.37     -79    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -76        48
#  comp.  2:       -89        49
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.148      0.32     -76    48
# Comp:  1                Halpha      4.626      0.32     -76    48
# Comp:  2             [SII]6716      2.727      0.32     -89    49
# Comp:  2             [SII]6731      1.240      0.32     -89    49
# Comp:  2              HeII4687     0.4628      0.32     -89    49
# Comp:  2               HeI5876     0.6036      0.32     -89    49
# Comp:  2          [OIII]5007_d      1.471      0.41     -89    49
# Comp:  2            [OI]6300_d     0.3501      0.41     -89    49
# Comp:  2           [NII]6583_d      1.568      0.41     -89    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -70        50
#  comp.  2:       -79        40
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.600      0.33     -70    50
# Comp:  1                Halpha      5.190      0.33     -70    50
# Comp:  2             [SII]6716      2.855      0.31     -79    40
# Comp:  2             [SII]6731      1.362      0.31     -79    40
# Comp:  2              HeII4687    0.04567      0.31     -79    40
# Comp:  2               HeI5876     0.6684      0.31     -79    40
# Comp:  2          [OIII]5007_d      1.192      0.40     -79    40
# Comp:  2            [OI]6300_d     0.5590      0.40     -79    40
# Comp:  2           [NII]6583_d      1.905      0.40     -79    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        99
#  comp.  1:       -70        50
#  comp.  2:       -82        31
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.071      0.33     -70    50
# Comp:  1                Halpha      4.577      0.33     -70    50
# Comp:  2             [SII]6716      2.538      0.31     -82    31
# Comp:  2             [SII]6731      1.257      0.31     -82    31
# Comp:  2              HeII4687    0.03628      0.31     -82    31
# Comp:  2               HeI5876     0.4218      0.31     -82    31
# Comp:  2          [OIII]5007_d      1.098      0.39     -82    31
# Comp:  2            [OI]6300_d     0.1517      0.39     -82    31
# Comp:  2           [NII]6583_d      1.642      0.39     -82    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -69        46
#  comp.  2:       -84        38
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.410      0.32     -69    46
# Comp:  1                Halpha      4.738      0.32     -69    46
# Comp:  2             [SII]6716      2.777      0.31     -84    38
# Comp:  2             [SII]6731      1.234      0.31     -84    38
# Comp:  2              HeII4687     0.5931      0.31     -84    38
# Comp:  2               HeI5876     0.7267      0.31     -84    38
# Comp:  2          [OIII]5007_d     0.9159      0.39     -84    38
# Comp:  2            [OI]6300_d     0.4794      0.39     -84    38
# Comp:  2           [NII]6583_d      1.834      0.39     -84    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        23
#  comp.  1:       -69        50
#  comp.  2:       -84        25
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.337      0.33     -69    50
# Comp:  1                Halpha      4.749      0.33     -69    50
# Comp:  2             [SII]6716      2.669      0.30     -84    25
# Comp:  2             [SII]6731      1.130      0.30     -84    25
# Comp:  2              HeII4687     0.6112      0.30     -84    25
# Comp:  2               HeI5876     0.7180      0.30     -84    25
# Comp:  2          [OIII]5007_d     0.9491      0.38     -84    25
# Comp:  2            [OI]6300_d     0.5236      0.38     -84    25
# Comp:  2           [NII]6583_d      1.801      0.38     -84    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        47
#  comp.  1:       -72        58
#  comp.  2:       -81        67
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.132      0.34     -72    58
# Comp:  1                Halpha      4.862      0.34     -72    58
# Comp:  2             [SII]6716      2.927      0.35     -81    67
# Comp:  2             [SII]6731      1.255      0.35     -81    67
# Comp:  2              HeII4687     0.3498      0.35     -81    67
# Comp:  2               HeI5876     0.7899      0.35     -81    67
# Comp:  2          [OIII]5007_d      2.308      0.44     -81    67
# Comp:  2            [OI]6300_d     0.8366      0.44     -81    67
# Comp:  2           [NII]6583_d      2.126      0.44     -81    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        56
#  comp.  1:       -75        45
#  comp.  2:       -85        55
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.116      0.32     -75    45
# Comp:  1                Halpha      4.432      0.32     -75    45
# Comp:  2             [SII]6716      2.786      0.33     -85    55
# Comp:  2             [SII]6731      1.444      0.33     -85    55
# Comp:  2              HeII4687     0.4450      0.33     -85    55
# Comp:  2               HeI5876     0.7535      0.33     -85    55
# Comp:  2          [OIII]5007_d      2.079      0.42     -85    55
# Comp:  2            [OI]6300_d     0.3137      0.42     -85    55
# Comp:  2           [NII]6583_d      1.870      0.42     -85    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        54
#  comp.  1:       -73        66
#  comp.  2:       -77        48
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.888      0.34     -73    66
# Comp:  1                Halpha      5.132      0.34     -73    66
# Comp:  2             [SII]6716      2.891      0.32     -77    48
# Comp:  2             [SII]6731      1.607      0.32     -77    48
# Comp:  2              HeII4687     0.1802      0.32     -77    48
# Comp:  2               HeI5876     0.7156      0.32     -77    48
# Comp:  2          [OIII]5007_d     0.8810      0.41     -77    48
# Comp:  2            [OI]6300_d     0.7889      0.41     -77    48
# Comp:  2           [NII]6583_d      1.972      0.41     -77    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        62
#  comp.  1:       -70        54
#  comp.  2:       -86        32
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.165      0.33     -70    54
# Comp:  1                Halpha      4.890      0.33     -70    54
# Comp:  2             [SII]6716      2.629      0.31     -86    32
# Comp:  2             [SII]6731      1.080      0.31     -86    32
# Comp:  2              HeII4687     0.2138      0.31     -86    32
# Comp:  2               HeI5876     0.5761      0.31     -86    32
# Comp:  2          [OIII]5007_d      1.240      0.39     -86    32
# Comp:  2            [OI]6300_d     0.8058      0.39     -86    32
# Comp:  2           [NII]6583_d      1.525      0.39     -86    32
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.34997131, 0.29974578, 0.29858842, 0.20289579, 0.2368697 ,
#        0.12377923, 0.38157732, 0.26939909, 0.2725689 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.10863366, 6.38484104, 3.8618491 , 1.84831138, 0.37035676,
#        0.71952077, 1.56595653, 0.75889999, 2.55810389])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_9_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_9", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_9_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_9_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_9_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.030111    0.009505
# 1        Halpha  0.173414    0.008141
# 2     [SII]6716  0.104889    0.008110
# 3     [SII]6731  0.050201    0.005511
# 4      HeII4687  0.010059    0.006433
# 5       HeI5876  0.019542    0.003362
# 6  [OIII]5007_d  0.042532    0.010364
# 7    [OI]6300_d  0.020612    0.007317
# 8   [NII]6583_d  0.069479    0.007403
#           Name      Flux  Error_flux
# 0        Hbeta  0.030111    0.009505
# 1       Halpha  0.173414    0.008141
# 2    [SII]6716  0.104889    0.008110
# 3    [SII]6731  0.050201    0.005511
# 4     HeII4687  0.010059    0.006433
# 5      HeI5876  0.019542    0.003362
# 6   [OIII]4959  0.010633    0.010364
# 7   [OIII]5007  0.031899    0.010364
# 8     [OI]6300  0.015459    0.007317
# 9     [OI]6364  0.005153    0.007317
# 10   [NII]6548  0.017370    0.007403
# 11   [NII]6583  0.052109    0.007403

# %%
np.median(flux_rf_rebin)
# Out:
# 0.027160248132105748
