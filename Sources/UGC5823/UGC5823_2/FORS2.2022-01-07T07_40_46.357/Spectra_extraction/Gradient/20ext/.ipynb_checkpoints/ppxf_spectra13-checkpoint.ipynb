# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_13.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188  
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_13']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.06099525 0.05970242 0.05271474 ... 0.04063637 0.0454619  0.04700326] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
# chi2/DOF: 0.009411; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
# chi2/DOF: 0.005863; DOF: 1898; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-81.69114735,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -75        27
#  comp.  2:       -78        23
# chi2/DOF: 0.9709; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.20      0.20     -75    27
# Comp:  1                Halpha      33.81      0.20     -75    27
# Comp:  2             [SII]6716      7.754      0.20     -78    23
# Comp:  2             [SII]6731      5.538      0.20     -78    23
# Comp:  2              HeII4687      0.000      0.20     -78    23
# Comp:  2               HeI5876      1.064      0.20     -78    23
# Comp:  2          [OIII]5007_d      10.47      0.25     -78    23
# Comp:  2            [OI]6300_d      1.788      0.25     -78    23
# Comp:  2           [NII]6583_d      12.13      0.25     -78    23
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  52.92; gas flux:     13 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  141.5; gas flux:     46 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  33.57; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  22.67; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  4.641; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  33.82; gas flux:     11 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   5.33; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  38.71; gas flux:     17 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        12
#  comp.  1:       -76        31
#  comp.  2:       -79        14
# chi2/DOF: 0.9581; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.72      0.20     -76    31
# Comp:  1                Halpha      34.63      0.20     -76    31
# Comp:  2             [SII]6716      7.618      0.19     -79    14
# Comp:  2             [SII]6731      5.558      0.19     -79    14
# Comp:  2              HeII4687      0.000      0.19     -79    14
# Comp:  2               HeI5876      1.130      0.19     -79    14
# Comp:  2          [OIII]5007_d      10.19      0.25     -79    14
# Comp:  2            [OI]6300_d      1.540      0.25     -79    14
# Comp:  2           [NII]6583_d      11.84      0.25     -79    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -72        29
#  comp.  2:       -79        20
# chi2/DOF: 0.9473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.31      0.20     -72    29
# Comp:  1                Halpha      33.96      0.20     -72    29
# Comp:  2             [SII]6716      7.758      0.20     -79    20
# Comp:  2             [SII]6731      5.454      0.20     -79    20
# Comp:  2              HeII4687      0.000      0.20     -79    20
# Comp:  2               HeI5876      1.145      0.20     -79    20
# Comp:  2          [OIII]5007_d      10.44      0.25     -79    20
# Comp:  2            [OI]6300_d      1.901      0.25     -79    20
# Comp:  2           [NII]6583_d      11.97      0.25     -79    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        55
#  comp.  1:       -77        25
#  comp.  2:       -75        24
# chi2/DOF: 0.9510; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.57      0.20     -77    25
# Comp:  1                Halpha      33.69      0.20     -77    25
# Comp:  2             [SII]6716      7.614      0.20     -75    24
# Comp:  2             [SII]6731      5.711      0.20     -75    24
# Comp:  2              HeII4687      0.000      0.20     -75    24
# Comp:  2               HeI5876      1.080      0.20     -75    24
# Comp:  2          [OIII]5007_d      10.44      0.25     -75    24
# Comp:  2            [OI]6300_d      1.612      0.25     -75    24
# Comp:  2           [NII]6583_d      12.09      0.25     -75    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        26
#  comp.  1:       -75        23
#  comp.  2:       -78        17
# chi2/DOF: 0.9249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.05      0.20     -75    23
# Comp:  1                Halpha      32.90      0.20     -75    23
# Comp:  2             [SII]6716      7.626      0.20     -78    17
# Comp:  2             [SII]6731      5.611      0.20     -78    17
# Comp:  2              HeII4687    0.04939      0.20     -78    17
# Comp:  2               HeI5876     0.9951      0.20     -78    17
# Comp:  2          [OIII]5007_d      10.34      0.25     -78    17
# Comp:  2            [OI]6300_d      1.571      0.25     -78    17
# Comp:  2           [NII]6583_d      11.75      0.25     -78    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -76        25
#  comp.  2:       -78        21
# chi2/DOF: 0.9461; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.81      0.20     -76    25
# Comp:  1                Halpha      33.54      0.20     -76    25
# Comp:  2             [SII]6716      7.972      0.20     -78    21
# Comp:  2             [SII]6731      5.415      0.20     -78    21
# Comp:  2              HeII4687      0.000      0.20     -78    21
# Comp:  2               HeI5876      1.103      0.20     -78    21
# Comp:  2          [OIII]5007_d      10.43      0.25     -78    21
# Comp:  2            [OI]6300_d      1.771      0.25     -78    21
# Comp:  2           [NII]6583_d      12.42      0.25     -78    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        14
#  comp.  1:       -76        20
#  comp.  2:       -75        29
# chi2/DOF: 0.9451; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.26      0.20     -76    20
# Comp:  1                Halpha      33.03      0.20     -76    20
# Comp:  2             [SII]6716      7.805      0.20     -75    29
# Comp:  2             [SII]6731      5.558      0.20     -75    29
# Comp:  2              HeII4687      0.000      0.20     -75    29
# Comp:  2               HeI5876      1.142      0.20     -75    29
# Comp:  2          [OIII]5007_d      10.75      0.25     -75    29
# Comp:  2            [OI]6300_d      1.751      0.25     -75    29
# Comp:  2           [NII]6583_d      12.47      0.25     -75    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -75        24
#  comp.  2:       -81        28
# chi2/DOF: 0.9613; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.30      0.20     -75    24
# Comp:  1                Halpha      33.37      0.20     -75    24
# Comp:  2             [SII]6716      7.709      0.20     -81    28
# Comp:  2             [SII]6731      5.845      0.20     -81    28
# Comp:  2              HeII4687    0.05028      0.20     -81    28
# Comp:  2               HeI5876      1.122      0.20     -81    28
# Comp:  2          [OIII]5007_d      10.64      0.25     -81    28
# Comp:  2            [OI]6300_d      1.759      0.25     -81    28
# Comp:  2           [NII]6583_d      12.32      0.25     -81    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        36
#  comp.  1:       -75        26
#  comp.  2:       -77        33
# chi2/DOF: 0.9164; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.50      0.20     -75    26
# Comp:  1                Halpha      33.70      0.20     -75    26
# Comp:  2             [SII]6716      7.903      0.20     -77    33
# Comp:  2             [SII]6731      5.855      0.20     -77    33
# Comp:  2              HeII4687      0.000      0.20     -77    33
# Comp:  2               HeI5876      1.190      0.20     -77    33
# Comp:  2          [OIII]5007_d      10.95      0.26     -77    33
# Comp:  2            [OI]6300_d      2.109      0.26     -77    33
# Comp:  2           [NII]6583_d      12.04      0.26     -77    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -75        22
#  comp.  2:       -76        27
# chi2/DOF: 0.9244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.30      0.20     -75    22
# Comp:  1                Halpha      32.93      0.20     -75    22
# Comp:  2             [SII]6716      7.943      0.20     -76    27
# Comp:  2             [SII]6731      5.563      0.20     -76    27
# Comp:  2              HeII4687     0.1777      0.20     -76    27
# Comp:  2               HeI5876      1.153      0.20     -76    27
# Comp:  2          [OIII]5007_d      10.50      0.25     -76    27
# Comp:  2            [OI]6300_d      1.862      0.25     -76    27
# Comp:  2           [NII]6583_d      12.24      0.25     -76    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:       -74        30
#  comp.  2:       -79        19
# chi2/DOF: 0.9601; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.81      0.20     -74    30
# Comp:  1                Halpha      34.07      0.20     -74    30
# Comp:  2             [SII]6716      7.747      0.20     -79    19
# Comp:  2             [SII]6731      5.611      0.20     -79    19
# Comp:  2              HeII4687      0.000      0.20     -79    19
# Comp:  2               HeI5876      1.101      0.20     -79    19
# Comp:  2          [OIII]5007_d      10.28      0.25     -79    19
# Comp:  2            [OI]6300_d      1.922      0.25     -79    19
# Comp:  2           [NII]6583_d      12.16      0.25     -79    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -76        25
#  comp.  2:       -76        17
# chi2/DOF: 0.9255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.23      0.20     -76    25
# Comp:  1                Halpha      34.30      0.20     -76    25
# Comp:  2             [SII]6716      7.593      0.20     -76    17
# Comp:  2             [SII]6731      5.578      0.20     -76    17
# Comp:  2              HeII4687     0.1585      0.20     -76    17
# Comp:  2               HeI5876     0.9558      0.20     -76    17
# Comp:  2          [OIII]5007_d      9.845      0.25     -76    17
# Comp:  2            [OI]6300_d      1.791      0.25     -76    17
# Comp:  2           [NII]6583_d      12.04      0.25     -76    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -76        32
#  comp.  2:       -78        21
# chi2/DOF: 0.9258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.55      0.20     -76    32
# Comp:  1                Halpha      34.48      0.20     -76    32
# Comp:  2             [SII]6716      7.654      0.20     -78    21
# Comp:  2             [SII]6731      5.535      0.20     -78    21
# Comp:  2              HeII4687      0.000      0.20     -78    21
# Comp:  2               HeI5876      1.076      0.20     -78    21
# Comp:  2          [OIII]5007_d      10.47      0.25     -78    21
# Comp:  2            [OI]6300_d      1.896      0.25     -78    21
# Comp:  2           [NII]6583_d      12.12      0.25     -78    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        22
#  comp.  1:       -76        25
#  comp.  2:       -79        24
# chi2/DOF: 0.9340; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.64      0.20     -76    25
# Comp:  1                Halpha      33.65      0.20     -76    25
# Comp:  2             [SII]6716      8.029      0.20     -79    24
# Comp:  2             [SII]6731      5.672      0.20     -79    24
# Comp:  2              HeII4687      0.000      0.20     -79    24
# Comp:  2               HeI5876      1.190      0.20     -79    24
# Comp:  2          [OIII]5007_d      10.66      0.25     -79    24
# Comp:  2            [OI]6300_d      1.665      0.25     -79    24
# Comp:  2           [NII]6583_d      12.29      0.25     -79    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        17
#  comp.  1:       -75        28
#  comp.  2:       -76        29
# chi2/DOF: 0.9285; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.47      0.20     -75    28
# Comp:  1                Halpha      33.57      0.20     -75    28
# Comp:  2             [SII]6716      8.116      0.20     -76    29
# Comp:  2             [SII]6731      5.500      0.20     -76    29
# Comp:  2              HeII4687      0.000      0.20     -76    29
# Comp:  2               HeI5876      1.087      0.20     -76    29
# Comp:  2          [OIII]5007_d      10.74      0.25     -76    29
# Comp:  2            [OI]6300_d      1.852      0.25     -76    29
# Comp:  2           [NII]6583_d      12.30      0.25     -76    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        44
#  comp.  1:       -74        23
#  comp.  2:       -80        21
# chi2/DOF: 0.9148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.15      0.20     -74    23
# Comp:  1                Halpha      33.40      0.20     -74    23
# Comp:  2             [SII]6716      7.802      0.20     -80    21
# Comp:  2             [SII]6731      5.372      0.20     -80    21
# Comp:  2              HeII4687    0.03697      0.20     -80    21
# Comp:  2               HeI5876      1.000      0.20     -80    21
# Comp:  2          [OIII]5007_d      10.27      0.25     -80    21
# Comp:  2            [OI]6300_d      1.842      0.25     -80    21
# Comp:  2           [NII]6583_d      11.78      0.25     -80    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        30
#  comp.  1:       -75        25
#  comp.  2:       -78        32
# chi2/DOF: 0.9276; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.27      0.20     -75    25
# Comp:  1                Halpha      33.43      0.20     -75    25
# Comp:  2             [SII]6716      8.003      0.20     -78    32
# Comp:  2             [SII]6731      5.518      0.20     -78    32
# Comp:  2              HeII4687      0.000      0.20     -78    32
# Comp:  2               HeI5876      1.179      0.20     -78    32
# Comp:  2          [OIII]5007_d      10.78      0.26     -78    32
# Comp:  2            [OI]6300_d      1.696      0.26     -78    32
# Comp:  2           [NII]6583_d      12.49      0.26     -78    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108         1
#  comp.  1:       -75        24
#  comp.  2:       -77         9
# chi2/DOF: 0.9171; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.89      0.20     -75    24
# Comp:  1                Halpha      33.37      0.20     -75    24
# Comp:  2             [SII]6716      7.709      0.19     -77     9
# Comp:  2             [SII]6731      5.471      0.19     -77     9
# Comp:  2              HeII4687     0.1638      0.19     -77     9
# Comp:  2               HeI5876      1.155      0.19     -77     9
# Comp:  2          [OIII]5007_d      9.858      0.24     -77     9
# Comp:  2            [OI]6300_d      1.710      0.24     -77     9
# Comp:  2           [NII]6583_d      12.01      0.24     -77     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:       -75        32
#  comp.  2:       -78        26
# chi2/DOF: 0.9181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.45      0.20     -75    32
# Comp:  1                Halpha      34.46      0.20     -75    32
# Comp:  2             [SII]6716      7.871      0.20     -78    26
# Comp:  2             [SII]6731      5.420      0.20     -78    26
# Comp:  2              HeII4687      0.000      0.20     -78    26
# Comp:  2               HeI5876      1.106      0.20     -78    26
# Comp:  2          [OIII]5007_d      10.45      0.25     -78    26
# Comp:  2            [OI]6300_d      1.576      0.25     -78    26
# Comp:  2           [NII]6583_d      12.23      0.25     -78    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -75        28
#  comp.  2:       -76        15
# chi2/DOF: 0.9192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.22      0.20     -75    28
# Comp:  1                Halpha      34.02      0.20     -75    28
# Comp:  2             [SII]6716      7.759      0.20     -76    15
# Comp:  2             [SII]6731      5.402      0.20     -76    15
# Comp:  2              HeII4687      0.000      0.20     -76    15
# Comp:  2               HeI5876      1.133      0.20     -76    15
# Comp:  2          [OIII]5007_d      9.908      0.25     -76    15
# Comp:  2            [OI]6300_d      1.901      0.25     -76    15
# Comp:  2           [NII]6583_d      11.43      0.25     -76    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -76        30
#  comp.  2:       -78        32
# chi2/DOF: 0.9171; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.31      0.20     -76    30
# Comp:  1                Halpha      34.30      0.20     -76    30
# Comp:  2             [SII]6716      7.781      0.20     -78    32
# Comp:  2             [SII]6731      5.801      0.20     -78    32
# Comp:  2              HeII4687     0.1003      0.20     -78    32
# Comp:  2               HeI5876      1.219      0.20     -78    32
# Comp:  2          [OIII]5007_d      11.07      0.26     -78    32
# Comp:  2            [OI]6300_d      1.836      0.26     -78    32
# Comp:  2           [NII]6583_d      12.50      0.26     -78    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -75        21
#  comp.  2:       -80        33
# chi2/DOF: 0.9155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.01      0.20     -75    21
# Comp:  1                Halpha      33.00      0.20     -75    21
# Comp:  2             [SII]6716      7.878      0.20     -80    33
# Comp:  2             [SII]6731      5.853      0.20     -80    33
# Comp:  2              HeII4687     0.2207      0.20     -80    33
# Comp:  2               HeI5876      1.141      0.20     -80    33
# Comp:  2          [OIII]5007_d      10.62      0.26     -80    33
# Comp:  2            [OI]6300_d      2.030      0.26     -80    33
# Comp:  2           [NII]6583_d      12.17      0.26     -80    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        42
#  comp.  1:       -76        26
#  comp.  2:       -80        16
# chi2/DOF: 0.9561; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.26      0.20     -76    26
# Comp:  1                Halpha      33.30      0.20     -76    26
# Comp:  2             [SII]6716      7.668      0.20     -80    16
# Comp:  2             [SII]6731      5.518      0.20     -80    16
# Comp:  2              HeII4687    0.06679      0.20     -80    16
# Comp:  2               HeI5876     0.9838      0.20     -80    16
# Comp:  2          [OIII]5007_d      10.45      0.25     -80    16
# Comp:  2            [OI]6300_d      1.861      0.25     -80    16
# Comp:  2           [NII]6583_d      12.08      0.25     -80    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106        20
#  comp.  1:       -77        29
#  comp.  2:       -79        30
# chi2/DOF: 0.9529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.75      0.20     -77    29
# Comp:  1                Halpha      34.43      0.20     -77    29
# Comp:  2             [SII]6716      7.944      0.20     -79    30
# Comp:  2             [SII]6731      5.743      0.20     -79    30
# Comp:  2              HeII4687    0.03623      0.20     -79    30
# Comp:  2               HeI5876      1.043      0.20     -79    30
# Comp:  2          [OIII]5007_d      11.02      0.26     -79    30
# Comp:  2            [OI]6300_d      1.774      0.26     -79    30
# Comp:  2           [NII]6583_d      12.31      0.26     -79    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         7
#  comp.  1:       -78        25
#  comp.  2:       -80        27
# chi2/DOF: 0.9535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.42      0.20     -78    25
# Comp:  1                Halpha      33.96      0.20     -78    25
# Comp:  2             [SII]6716      7.936      0.20     -80    27
# Comp:  2             [SII]6731      5.647      0.20     -80    27
# Comp:  2              HeII4687     0.2361      0.20     -80    27
# Comp:  2               HeI5876     0.9978      0.20     -80    27
# Comp:  2          [OIII]5007_d      10.58      0.25     -80    27
# Comp:  2            [OI]6300_d      1.773      0.25     -80    27
# Comp:  2           [NII]6583_d      12.00      0.25     -80    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -75        28
#  comp.  2:       -78        31
# chi2/DOF: 0.9541; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.40      0.20     -75    28
# Comp:  1                Halpha      33.52      0.20     -75    28
# Comp:  2             [SII]6716      8.128      0.20     -78    31
# Comp:  2             [SII]6731      5.450      0.20     -78    31
# Comp:  2              HeII4687      0.000      0.20     -78    31
# Comp:  2               HeI5876      1.133      0.20     -78    31
# Comp:  2          [OIII]5007_d      11.33      0.26     -78    31
# Comp:  2            [OI]6300_d      1.763      0.26     -78    31
# Comp:  2           [NII]6583_d      12.56      0.26     -78    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -75        22
#  comp.  2:       -78        29
# chi2/DOF: 0.9563; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.24      0.20     -75    22
# Comp:  1                Halpha      33.23      0.20     -75    22
# Comp:  2             [SII]6716      7.763      0.20     -78    29
# Comp:  2             [SII]6731      5.669      0.20     -78    29
# Comp:  2              HeII4687     0.1690      0.20     -78    29
# Comp:  2               HeI5876     0.9912      0.20     -78    29
# Comp:  2          [OIII]5007_d      10.83      0.25     -78    29
# Comp:  2            [OI]6300_d      1.762      0.25     -78    29
# Comp:  2           [NII]6583_d      12.04      0.25     -78    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        38
#  comp.  1:       -77        28
#  comp.  2:       -79        29
# chi2/DOF: 0.9452; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.16      0.20     -77    28
# Comp:  1                Halpha      34.54      0.20     -77    28
# Comp:  2             [SII]6716      7.900      0.20     -79    29
# Comp:  2             [SII]6731      5.511      0.20     -79    29
# Comp:  2              HeII4687      0.000      0.20     -79    29
# Comp:  2               HeI5876      1.215      0.20     -79    29
# Comp:  2          [OIII]5007_d      10.97      0.25     -79    29
# Comp:  2            [OI]6300_d      1.739      0.25     -79    29
# Comp:  2           [NII]6583_d      12.14      0.25     -79    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -76        23
#  comp.  2:       -79        28
# chi2/DOF: 0.9317; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.88      0.20     -76    23
# Comp:  1                Halpha      33.74      0.20     -76    23
# Comp:  2             [SII]6716      7.736      0.20     -79    28
# Comp:  2             [SII]6731      5.716      0.20     -79    28
# Comp:  2              HeII4687      0.000      0.20     -79    28
# Comp:  2               HeI5876      1.024      0.20     -79    28
# Comp:  2          [OIII]5007_d      10.51      0.25     -79    28
# Comp:  2            [OI]6300_d      1.978      0.25     -79    28
# Comp:  2           [NII]6583_d      12.39      0.25     -79    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -77        28
#  comp.  2:       -75        22
# chi2/DOF: 0.9191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.63      0.20     -77    28
# Comp:  1                Halpha      34.39      0.20     -77    28
# Comp:  2             [SII]6716      7.674      0.20     -75    22
# Comp:  2             [SII]6731      5.465      0.20     -75    22
# Comp:  2              HeII4687      0.000      0.20     -75    22
# Comp:  2               HeI5876      1.182      0.20     -75    22
# Comp:  2          [OIII]5007_d      10.68      0.25     -75    22
# Comp:  2            [OI]6300_d      1.843      0.25     -75    22
# Comp:  2           [NII]6583_d      12.27      0.25     -75    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        42
#  comp.  1:       -74        20
#  comp.  2:       -79        14
# chi2/DOF: 0.9246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.72      0.20     -74    20
# Comp:  1                Halpha      33.02      0.20     -74    20
# Comp:  2             [SII]6716      7.714      0.19     -79    14
# Comp:  2             [SII]6731      5.472      0.19     -79    14
# Comp:  2              HeII4687      0.000      0.19     -79    14
# Comp:  2               HeI5876      1.168      0.19     -79    14
# Comp:  2          [OIII]5007_d      10.07      0.25     -79    14
# Comp:  2            [OI]6300_d      1.814      0.25     -79    14
# Comp:  2           [NII]6583_d      12.22      0.25     -79    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -74        27
#  comp.  2:       -79        32
# chi2/DOF: 0.9565; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.84      0.20     -74    27
# Comp:  1                Halpha      33.34      0.20     -74    27
# Comp:  2             [SII]6716      8.099      0.20     -79    32
# Comp:  2             [SII]6731      5.816      0.20     -79    32
# Comp:  2              HeII4687      0.000      0.20     -79    32
# Comp:  2               HeI5876      1.023      0.20     -79    32
# Comp:  2          [OIII]5007_d      10.94      0.26     -79    32
# Comp:  2            [OI]6300_d      1.682      0.26     -79    32
# Comp:  2           [NII]6583_d      12.32      0.26     -79    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93         1
#  comp.  1:       -75        25
#  comp.  2:       -76        23
# chi2/DOF: 0.9242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.34      0.20     -75    25
# Comp:  1                Halpha      33.22      0.20     -75    25
# Comp:  2             [SII]6716      7.883      0.20     -76    23
# Comp:  2             [SII]6731      5.718      0.20     -76    23
# Comp:  2              HeII4687    0.08233      0.20     -76    23
# Comp:  2               HeI5876      1.192      0.20     -76    23
# Comp:  2          [OIII]5007_d      10.53      0.25     -76    23
# Comp:  2            [OI]6300_d      1.897      0.25     -76    23
# Comp:  2           [NII]6583_d      11.92      0.25     -76    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94        42
#  comp.  1:       -74        19
#  comp.  2:       -76        22
# chi2/DOF: 0.9227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74      0.20     -74    19
# Comp:  1                Halpha      33.00      0.20     -74    19
# Comp:  2             [SII]6716      7.922      0.20     -76    22
# Comp:  2             [SII]6731      5.361      0.20     -76    22
# Comp:  2              HeII4687    0.01885      0.20     -76    22
# Comp:  2               HeI5876      1.012      0.20     -76    22
# Comp:  2          [OIII]5007_d      10.30      0.25     -76    22
# Comp:  2            [OI]6300_d      1.765      0.25     -76    22
# Comp:  2           [NII]6583_d      12.40      0.25     -76    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:       -73        25
#  comp.  2:       -76        19
# chi2/DOF: 0.9516; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.68      0.20     -73    25
# Comp:  1                Halpha      33.41      0.20     -73    25
# Comp:  2             [SII]6716      7.903      0.20     -76    19
# Comp:  2             [SII]6731      5.517      0.20     -76    19
# Comp:  2              HeII4687      0.000      0.20     -76    19
# Comp:  2               HeI5876      1.126      0.20     -76    19
# Comp:  2          [OIII]5007_d      10.18      0.25     -76    19
# Comp:  2            [OI]6300_d      1.681      0.25     -76    19
# Comp:  2           [NII]6583_d      11.92      0.25     -76    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        42
#  comp.  1:       -76        27
#  comp.  2:       -79        19
# chi2/DOF: 0.9604; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.65      0.20     -76    27
# Comp:  1                Halpha      34.12      0.20     -76    27
# Comp:  2             [SII]6716      7.766      0.20     -79    19
# Comp:  2             [SII]6731      5.353      0.20     -79    19
# Comp:  2              HeII4687     0.1526      0.20     -79    19
# Comp:  2               HeI5876      1.053      0.20     -79    19
# Comp:  2          [OIII]5007_d      10.36      0.25     -79    19
# Comp:  2            [OI]6300_d      1.889      0.25     -79    19
# Comp:  2           [NII]6583_d      12.07      0.25     -79    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        14
#  comp.  1:       -73        31
#  comp.  2:       -77        22
# chi2/DOF: 0.9575; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.04      0.20     -73    31
# Comp:  1                Halpha      34.02      0.20     -73    31
# Comp:  2             [SII]6716      7.921      0.20     -77    22
# Comp:  2             [SII]6731      5.669      0.20     -77    22
# Comp:  2              HeII4687      0.000      0.20     -77    22
# Comp:  2               HeI5876      1.098      0.20     -77    22
# Comp:  2          [OIII]5007_d      10.07      0.25     -77    22
# Comp:  2            [OI]6300_d      1.967      0.25     -77    22
# Comp:  2           [NII]6583_d      12.25      0.25     -77    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        49
#  comp.  1:       -75        29
#  comp.  2:       -75        17
# chi2/DOF: 0.9171; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.61      0.20     -75    29
# Comp:  1                Halpha      34.48      0.20     -75    29
# Comp:  2             [SII]6716      7.514      0.20     -75    17
# Comp:  2             [SII]6731      5.283      0.20     -75    17
# Comp:  2              HeII4687      0.000      0.20     -75    17
# Comp:  2               HeI5876     0.9961      0.20     -75    17
# Comp:  2          [OIII]5007_d      9.899      0.25     -75    17
# Comp:  2            [OI]6300_d      1.817      0.25     -75    17
# Comp:  2           [NII]6583_d      11.95      0.25     -75    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        13
#  comp.  1:       -74        26
#  comp.  2:       -79        27
# chi2/DOF: 0.9230; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.12      0.20     -74    26
# Comp:  1                Halpha      33.37      0.20     -74    26
# Comp:  2             [SII]6716      7.853      0.20     -79    27
# Comp:  2             [SII]6731      5.478      0.20     -79    27
# Comp:  2              HeII4687      0.000      0.20     -79    27
# Comp:  2               HeI5876      1.074      0.20     -79    27
# Comp:  2          [OIII]5007_d      11.04      0.25     -79    27
# Comp:  2            [OI]6300_d      1.820      0.25     -79    27
# Comp:  2           [NII]6583_d      12.71      0.25     -79    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101         1
#  comp.  1:       -73        24
#  comp.  2:       -76        16
# chi2/DOF: 0.9504; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.20     -73    24
# Comp:  1                Halpha      33.46      0.20     -73    24
# Comp:  2             [SII]6716      7.699      0.20     -76    16
# Comp:  2             [SII]6731      5.419      0.20     -76    16
# Comp:  2              HeII4687      0.000      0.20     -76    16
# Comp:  2               HeI5876     0.9837      0.20     -76    16
# Comp:  2          [OIII]5007_d      10.25      0.25     -76    16
# Comp:  2            [OI]6300_d      1.565      0.25     -76    16
# Comp:  2           [NII]6583_d      11.87      0.25     -76    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -74        28
#  comp.  2:       -79        30
# chi2/DOF: 0.9564; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.76      0.20     -74    28
# Comp:  1                Halpha      33.76      0.20     -74    28
# Comp:  2             [SII]6716      8.031      0.20     -79    30
# Comp:  2             [SII]6731      5.603      0.20     -79    30
# Comp:  2              HeII4687      0.000      0.20     -79    30
# Comp:  2               HeI5876      1.057      0.20     -79    30
# Comp:  2          [OIII]5007_d      11.23      0.26     -79    30
# Comp:  2            [OI]6300_d      1.543      0.26     -79    30
# Comp:  2           [NII]6583_d      12.37      0.26     -79    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98         1
#  comp.  1:       -76        32
#  comp.  2:       -75        29
# chi2/DOF: 0.9106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.39      0.20     -76    32
# Comp:  1                Halpha      34.54      0.20     -76    32
# Comp:  2             [SII]6716      7.848      0.20     -75    29
# Comp:  2             [SII]6731      5.566      0.20     -75    29
# Comp:  2              HeII4687    0.01323      0.20     -75    29
# Comp:  2               HeI5876      1.155      0.20     -75    29
# Comp:  2          [OIII]5007_d      10.39      0.25     -75    29
# Comp:  2            [OI]6300_d      1.777      0.25     -75    29
# Comp:  2           [NII]6583_d      12.28      0.25     -75    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -78        25
#  comp.  2:       -77        30
# chi2/DOF: 0.9152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.43      0.20     -78    25
# Comp:  1                Halpha      34.11      0.20     -78    25
# Comp:  2             [SII]6716      7.712      0.20     -77    30
# Comp:  2             [SII]6731      5.699      0.20     -77    30
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.34      0.20     -73    28
# Comp:  1                Halpha      33.62      0.20     -73    28
# Comp:  2             [SII]6716      7.375      0.19     -76     9
# Comp:  2             [SII]6731      5.313      0.19     -76     9
# Comp:  2              HeII4687    0.06913      0.19     -76     9
# Comp:  2               HeI5876      1.150      0.19     -76     9
# Comp:  2          [OIII]5007_d      9.877      0.24     -76     9
# Comp:  2            [OI]6300_d      1.930      0.24     -76     9
# Comp:  2           [NII]6583_d      11.90      0.24     -76     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -76        31
#  comp.  2:       -74        28
# chi2/DOF: 0.9588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.47      0.20     -76    31
# Comp:  1                Halpha      34.44      0.20     -76    31
# Comp:  2             [SII]6716      7.856      0.20     -74    28
# Comp:  2             [SII]6731      5.588      0.20     -74    28
# Comp:  2              HeII4687     0.1813      0.20     -74    28
# Comp:  2               HeI5876      1.152      0.20     -74    28
# Comp:  2          [OIII]5007_d      10.20      0.25     -74    28
# Comp:  2            [OI]6300_d      1.918      0.25     -74    28
# Comp:  2           [NII]6583_d      12.25      0.25     -74    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -75        30
#  comp.  2:       -77        27
# chi2/DOF: 0.9629; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.21      0.20     -75    30
# Comp:  1                Halpha      34.43      0.20     -75    30
# Comp:  2             [SII]6716      7.567      0.20     -77    27
# Comp:  2             [SII]6731      5.645      0.20     -77    27
# Comp:  2              HeII4687      0.000      0.20     -77    27
# Comp:  2               HeI5876     0.9739      0.20     -77    27
# Comp:  2          [OIII]5007_d      10.57      0.25     -77    27
# Comp:  2            [OI]6300_d      1.863      0.25     -77    27
# Comp:  2           [NII]6583_d      12.20      0.25     -77    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        68
#  comp.  1:       -75        29
#  comp.  2:       -78         4
# chi2/DOF: 0.9513; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.49      0.20     -75    29
# Comp:  1                Halpha      34.28      0.20     -75    29
# Comp:  2             [SII]6716      7.602      0.19     -78     4
# Comp:  2             [SII]6731      5.545      0.19     -78     4
# Comp:  2              HeII4687      0.000      0.19     -78     4
# Comp:  2               HeI5876     0.9959      0.19     -78     4
# Comp:  2          [OIII]5007_d      10.14      0.24     -78     4
# Comp:  2            [OI]6300_d      1.779      0.24     -78     4
# Comp:  2           [NII]6583_d      11.65      0.24     -78     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        29
#  comp.  1:       -76        22
#  comp.  2:       -78        23
# chi2/DOF: 0.9292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.84      0.20     -76    22
# Comp:  1                Halpha      33.66      0.20     -76    22
# Comp:  2             [SII]6716      7.674      0.20     -78    23
# Comp:  2             [SII]6731      5.669      0.20     -78    23
# Comp:  2              HeII4687      0.000      0.20     -78    23
# Comp:  2               HeI5876      1.092      0.20     -78    23
# Comp:  2          [OIII]5007_d      10.30      0.25     -78    23
# Comp:  2            [OI]6300_d      1.645      0.25     -78    23
# Comp:  2           [NII]6583_d      12.26      0.25     -78    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -76        21
#  comp.  2:       -77         1
# chi2/DOF: 0.9105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.97      0.20     -76    21
# Comp:  1                Halpha      33.06      0.20     -76    21
# Comp:  2             [SII]6716      7.296      0.19     -77     1
# Comp:  2             [SII]6731      5.443      0.19     -77     1
# Comp:  2              HeII4687      0.000      0.19     -77     1
# Comp:  2               HeI5876      1.066      0.19     -77     1
# Comp:  2          [OIII]5007_d      10.11      0.24     -77     1
# Comp:  2            [OI]6300_d      1.637      0.24     -77     1
# Comp:  2           [NII]6583_d      12.01      0.24     -77     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90         1
#  comp.  1:       -75        25
#  comp.  2:       -77        24
# chi2/DOF: 0.9622; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.12      0.20     -75    25
# Comp:  1                Halpha      33.31      0.20     -75    25
# Comp:  2             [SII]6716      7.604      0.20     -77    24
# Comp:  2             [SII]6731      5.654      0.20     -77    24
# Comp:  2              HeII4687      0.000      0.20     -77    24
# Comp:  2               HeI5876      1.023      0.20     -77    24
# Comp:  2          [OIII]5007_d      10.37      0.25     -77    24
# Comp:  2            [OI]6300_d      1.784      0.25     -77    24
# Comp:  2           [NII]6583_d      12.24      0.25     -77    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        29
#  comp.  1:       -77        28
#  comp.  2:       -80        19
# chi2/DOF: 0.9529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.58      0.20     -77    28
# Comp:  1                Halpha      34.25      0.20     -77    28
# Comp:  2             [SII]6716      7.717      0.20     -80    19
# Comp:  2             [SII]6731      5.426      0.20     -80    19
# Comp:  2              HeII4687      0.000      0.20     -80    19
# Comp:  2               HeI5876      1.173      0.20     -80    19
# Comp:  2          [OIII]5007_d      10.72      0.25     -80    19
# Comp:  2            [OI]6300_d      1.638      0.25     -80    19
# Comp:  2           [NII]6583_d      12.13      0.25     -80    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        24
#  comp.  1:       -77        26
#  comp.  2:       -77        34
# chi2/DOF: 0.9144; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74      0.20     -77    26
# Comp:  1                Halpha      33.68      0.20     -77    26
# Comp:  2             [SII]6716      8.020      0.20     -77    34
# Comp:  2             [SII]6731      5.904      0.20     -77    34
# Comp:  2              HeII4687      0.000      0.20     -77    34
# Comp:  2               HeI5876      1.173      0.20     -77    34
# Comp:  2          [OIII]5007_d      10.91      0.26     -77    34
# Comp:  2            [OI]6300_d      1.661      0.26     -77    34
# Comp:  2           [NII]6583_d      12.50      0.26     -77    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99         1
#  comp.  1:       -75        32
#  comp.  2:       -77        16
# chi2/DOF: 0.9528; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.20     -75    32
# Comp:  1                Halpha      34.46      0.20     -75    32
# Comp:  2             [SII]6716      7.805      0.20     -77    16
# Comp:  2             [SII]6731      5.547      0.20     -77    16
# Comp:  2              HeII4687    0.05650      0.20     -77    16
# Comp:  2               HeI5876     0.9791      0.20     -77    16
# Comp:  2          [OIII]5007_d      10.06      0.25     -77    16
# Comp:  2            [OI]6300_d      1.741      0.25     -77    16
# Comp:  2           [NII]6583_d      11.46      0.25     -77    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:       -73        29
#  comp.  2:       -79        18
# chi2/DOF: 0.9559; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.20     -73    29
# Comp:  1                Halpha      33.72      0.20     -73    29
# Comp:  2             [SII]6716      7.733      0.20     -79    18
# Comp:  2             [SII]6731      5.669      0.20     -79    18
# Comp:  2              HeII4687      0.000      0.20     -79    18
# Comp:  2               HeI5876      1.036      0.20     -79    18
# Comp:  2          [OIII]5007_d      10.22      0.25     -79    18
# Comp:  2            [OI]6300_d      1.765      0.25     -79    18
# Comp:  2           [NII]6583_d      11.89      0.25     -79    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       -75        19
#  comp.  2:       -77        18
# chi2/DOF: 0.9101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.79      0.20     -75    19
# Comp:  1                Halpha      32.87      0.20     -75    19
# Comp:  2             [SII]6716      7.526      0.20     -77    18
# Comp:  2             [SII]6731      5.321      0.20     -77    18
# Comp:  2              HeII4687      0.000      0.20     -77    18
# Comp:  2               HeI5876     0.9860      0.20     -77    18
# Comp:  2          [OIII]5007_d      9.997      0.25     -77    18
# Comp:  2            [OI]6300_d      1.814      0.25     -77    18
# Comp:  2           [NII]6583_d      12.11      0.25     -77    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        29
#  comp.  1:       -75        26
#  comp.  2:       -78        28
# chi2/DOF: 0.9546; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.64      0.20     -75    26
# Comp:  1                Halpha      33.57      0.20     -75    26
# Comp:  2             [SII]6716      7.752      0.20     -78    28
# Comp:  2             [SII]6731      5.367      0.20     -78    28
# Comp:  2              HeII4687     0.1999      0.20     -78    28
# Comp:  2               HeI5876      1.056      0.20     -78    28
# Comp:  2          [OIII]5007_d      10.54      0.25     -78    28
# Comp:  2            [OI]6300_d      1.995      0.25     -78    28
# Comp:  2           [NII]6583_d      11.96      0.25     -78    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        44
#  comp.  1:       -77        32
#  comp.  2:       -80        26
# chi2/DOF: 0.9507; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.62      0.20     -77    32
# Comp:  1                Halpha      34.41      0.20     -77    32
# Comp:  2             [SII]6716      7.985      0.20     -80    26
# Comp:  2             [SII]6731      5.821      0.20     -80    26
# Comp:  2              HeII4687      0.000      0.20     -80    26
# Comp:  2               HeI5876      1.099      0.20     -80    26
# Comp:  2          [OIII]5007_d      10.85      0.25     -80    26
# Comp:  2            [OI]6300_d      1.873      0.25     -80    26
# Comp:  2           [NII]6583_d      12.36      0.25     -80    26
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.32388003, 0.67584387, 0.25584224, 0.22171071, 0.07854547,
#        0.08661433, 0.37885535, 0.20286459, 0.36424958])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([13.38611998, 46.28573299, 10.86273288,  7.77454657,  0.        ,
#         1.30415439, 10.9330174 ,  2.34937262, 16.65955632])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_13_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_13", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_13_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_13_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_13_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.685489    0.067794
# 1        Halpha  2.370242    0.034609
# 2     [SII]6716  0.556269    0.013101
# 3     [SII]6731  0.398126    0.011354
# 4      HeII4687  0.000000    0.004022
# 5       HeI5876  0.066784    0.004435
# 6  [OIII]5007_d  0.559868    0.019401
# 7    [OI]6300_d  0.120309    0.010388
# 8   [NII]6583_d  0.853118    0.018653
#           Name      Flux  Error_flux
# 0        Hbeta  0.685489    0.067794
# 1       Halpha  2.370242    0.034609
# 2    [SII]6716  0.556269    0.013101
# 3    [SII]6731  0.398126    0.011354
# 4     HeII4687  0.000000    0.004022
# 5      HeI5876  0.066784    0.004435
# 6   [OIII]4959  0.139967    0.019401
# 7   [OIII]5007  0.419901    0.019401
# 8     [OI]6300  0.090232    0.010388
# 9     [OI]6364  0.030077    0.010388
# 10   [NII]6548  0.213279    0.018653
# 11   [NII]6583  0.639838    0.018653

# %%
np.median(flux_rf_rebin)
# Out:
# 0.05120891156059357
