# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_11.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_11']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.0623844  0.06061335 0.05247942 ... 0.03521051 0.03408967 0.03516929] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
# chi2/DOF: 0.01221; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
# chi2/DOF: 0.008141; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-66.96174024,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -76        29
#  comp.  2:       -79        31
# chi2/DOF: 0.9554; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.88      0.23     -76    29
# Comp:  1                Halpha      33.66      0.23     -76    29
# Comp:  2             [SII]6716      7.512      0.23     -79    31
# Comp:  2             [SII]6731      5.191      0.23     -79    31
# Comp:  2              HeII4687      0.000      0.23     -79    31
# Comp:  2               HeI5876      1.142      0.23     -79    31
# Comp:  2          [OIII]5007_d      8.330      0.29     -79    31
# Comp:  2            [OI]6300_d     0.9336      0.29     -79    31
# Comp:  2           [NII]6583_d      11.21      0.29     -79    31
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        69
#  comp.  1:       -79        28
#  comp.  2:       -79        31
# chi2/DOF: 0.9321; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls:
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        11
#  comp.  1:       -77        31
#  comp.  2:       -80        31
# chi2/DOF: 0.9372; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.75      0.23     -77    31
# Comp:  1                Halpha      34.06      0.23     -77    31
# Comp:  2             [SII]6716      7.499      0.23     -80    31
# Comp:  2             [SII]6731      5.096      0.23     -80    31
# Comp:  2              HeII4687      0.000      0.23     -80    31
# Comp:  2               HeI5876      1.172      0.23     -80    31
# Comp:  2          [OIII]5007_d      8.669      0.29     -80    31
# Comp:  2            [OI]6300_d      1.113      0.29     -80    31
# Comp:  2           [NII]6583_d      11.20      0.29     -80    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        26
#  comp.  1:       -74        28
#  comp.  2:       -79        24
# chi2/DOF: 0.9293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.70      0.23     -74    28
# Comp:  1                Halpha      33.56      0.23     -74    28
# Comp:  2             [SII]6716      7.268      0.23     -79    24
# Comp:  2             [SII]6731      5.241      0.23     -79    24
# Comp:  2              HeII4687      0.000      0.23     -79    24
# Comp:  2               HeI5876      1.159      0.23     -79    24
# Comp:  2          [OIII]5007_d      7.756      0.29     -79    24
# Comp:  2            [OI]6300_d     0.9667      0.29     -79    24
# Comp:  2           [NII]6583_d      11.23      0.29     -79    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -77        32
#  comp.  2:       -77        24
# chi2/DOF: 0.9169; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.791      0.23     -77    32
# Comp:  1                Halpha      34.48      0.23     -77    32
# Comp:  2             [SII]6716      7.191      0.23     -77    24
# Comp:  2             [SII]6731      5.017      0.23     -77    24
# Comp:  2              HeII4687     0.1417      0.23     -77    24
# Comp:  2               HeI5876     0.8880      0.23     -77    24
# Comp:  2          [OIII]5007_d      7.791      0.29     -77    24
# Comp:  2            [OI]6300_d      1.221      0.29     -77    24
# Comp:  2           [NII]6583_d      10.95      0.29     -77    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -76        27
#  comp.  2:       -80        30
# chi2/DOF: 0.9384; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.795      0.23     -76    27
# Comp:  1                Halpha      33.24      0.23     -76    27
# Comp:  2             [SII]6716      7.485      0.23     -80    30
# Comp:  2             [SII]6731      5.188      0.23     -80    30
# Comp:  2              HeII4687      0.000      0.23     -80    30
# Comp:  2               HeI5876     0.9805      0.23     -80    30
# Comp:  2          [OIII]5007_d      8.309      0.29     -80    30
# Comp:  2            [OI]6300_d     0.8711      0.29     -80    30
# Comp:  2           [NII]6583_d      11.70      0.29     -80    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:       -77        33
#  comp.  2:       -78        37
# chi2/DOF: 0.9273; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.49      0.23     -77    33
# Comp:  1                Halpha      34.32      0.23     -77    33
# Comp:  2             [SII]6716      7.827      0.24     -78    37
# Comp:  2             [SII]6731      5.241      0.24     -78    37
# Comp:  2              HeII4687    0.08813      0.24     -78    37
# Comp:  2               HeI5876      1.457      0.24     -78    37
# Comp:  2          [OIII]5007_d      8.183      0.30     -78    37
# Comp:  2            [OI]6300_d      1.330      0.30     -78    37
# Comp:  2           [NII]6583_d      11.24      0.30     -78    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       
Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.31      0.23     -76    25
# Comp:  1                Halpha      33.03      0.23     -76    25
# Comp:  2             [SII]6716      7.512      0.23     -79    28
# Comp:  2             [SII]6731      5.285      0.23     -79    28
# Comp:  2              HeII4687      0.000      0.23     -79    28
# Comp:  2               HeI5876     0.9810      0.23     -79    28
# Comp:  2          [OIII]5007_d      7.878      0.29     -79    28
# Comp:  2            [OI]6300_d     0.6350      0.29     -79    28
# Comp:  2           [NII]6583_d      10.89      0.29     -79    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        50
#  comp.  1:       -73        30
#  comp.  2:       -82        28
# chi2/DOF: 0.9165; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.23     -73    30
# Comp:  1                Halpha      33.85      0.23     -73    30
# Comp:  2             [SII]6716      7.209      0.23     -82    28
# Comp:  2             [SII]6731      5.283      0.23     -82    28
# Comp:  2              HeII4687      0.000      0.23     -82    28
# Comp:  2               HeI5876     0.9643      0.23     -82    28
# Comp:  2          [OIII]5007_d      8.367      0.29     -82    28
# Comp:  2            [OI]6300_d     0.7565      0.29     -82    28
# Comp:  2           [NII]6583_d      11.06      0.29     -82    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -74        31
#  comp.  2:       -78        34
# chi2/DOF: 0.9204; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.77      0.23     -74    31
# Comp:  1                Halpha      34.08      0.23     -74    31
# Comp:  2             [SII]6716      7.763      0.23     -78    34
# Comp:  2             [SII]6731      5.363      0.23     -78    34
# Comp:  2              HeII4687     0.1172      0.23     -78    34
# Comp:  2               HeI5876      1.170      0.23     -78    34
# Comp:  2          [OIII]5007_d      8.768      0.30     -78    34
# Comp:  2            [OI]6300_d      1.126      0.30     -78    34
# Comp:  2           [NII]6583_d      11.87      0.30     -78    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -76        30
#  comp.  2:       -77        32
# chi2/DOF: 0.9209; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.18      0.23     -76    30
# Comp:  1                Halpha      34.40      0.23     -76    30
# Comp:  2             [SII]6716      7.647      0.23     -77    32
# Comp:  2             [SII]6731      4.927      0.23     -77    32
# Comp:  2              HeII4687      0.000      0.23     -77    32
# Comp:  2               HeI5876      1.012      0.23     -77    32
# Comp:  2          [OIII]5007_d      8.431      0.29     -77    32
# Comp:  2            [OI]6300_d     0.9301      0.29     -77    32
# Comp:  2           [NII]6583_d      10.88      0.29     -77    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -77        29
#  comp.  2:       -81        27
# chi2/DOF: 0.9385; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.55      0.23     -77    29
# Comp:  1                Halpha      34.14      0.23     -77    29
# Comp:  2             [SII]6716      7.284      0.23     -81    27
# Comp:  2             [SII]6731      5.020      0.23     -81    27
# Comp:  2              HeII4687     0.1468      0.23     -81    27
# Comp:  2               HeI5876     0.9199      0.23     -81    27
# Comp:  2          [OIII]5007_d      7.832      0.29     -81    27
# Comp:  2            [OI]6300_d      1.118      0.29     -81    27
# Comp:  2           [NII]6583_d      11.16      0.29     -81    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         7
#  comp.  1:       -77        30
#  comp.  2:       -79        34
# chi2/DOF: 0.9446; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.77      0.23     -77    30
# Comp:  1                Halpha      34.35      0.23     -77    30
# Comp:  2             [SII]6716      7.745      0.23     -79    34
# Comp:  2             [SII]6731      5.263      0.23     -79    34
# Comp:  2              HeII4687      0.000      0.23     -79    34
# Comp:  2               HeI5876      1.203      0.23     -79    34
# Comp:  2          [OIII]5007_d      8.800      0.30     -79    34
# Comp:  2            [OI]6300_d      1.008      0.30     -79    34
# Comp:  2           [NII]6583_d      11.21      0.30     -79    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        21
#  comp.  1:       -75        27
#  comp.  2:       -79        32
# chi2/DOF: 0.9327; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.23      0.23     -75    27
# Comp:  1                Halpha      33.42      0.23     -75    27
# Comp:  2             [SII]6716      7.605      0.23     -79    32
# Comp:  2             [SII]6731      5.215      0.23     -79    32
# Comp:  2              HeII4687      0.000      0.23     -79    32
# Comp:  2               HeI5876      1.114      0.23     -79    32
# Comp:  2          [OIII]5007_d      8.427      0.29     -79    32
# Comp:  2            [OI]6300_d      1.271      0.29     -79    32
# Comp:  2           [NII]6583_d      11.60      0.29     -79    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        56
#  comp.  1:       -77        31
#  comp.  2:       -80        33
# chi2/DOF: 0.9188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.44      0.23     -77    31
# Comp:  1                Halpha      33.84      0.23     -77    31
# Comp:  2             [SII]6716      7.770      0.23     -80    33
# Comp:  2             [SII]6731      5.058      0.23     -80    33
# Comp:  2              HeII4687     0.1327      0.23     -80    33
# Comp:  2               HeI5876      1.201      0.23     -80    33
# Comp:  2          [OIII]5007_d      8.542      0.30     -80    33
# Comp:  2            [OI]6300_d      1.039      0.30     -80    33
# Comp:  2           [NII]6583_d      11.47      0.30     -80    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        26
#  comp.  1:       -77        32
#  comp.  2:       -80        33
# chi2/DOF: 0.9469; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.99      0.23     -77    32
# Comp:  1                Halpha      34.36      0.23     -77    32
# Comp:  2             [SII]6716      7.794      0.23     -80    33
# Comp:  2             [SII]6731      5.258      0.23     -80    33
# Comp:  2              HeII4687    0.02749      0.23     -80    33
# Comp:  2               HeI5876      1.218      0.23     -80    33
# Comp:  2          [OIII]5007_d      8.639      0.30     -80    33
# Comp:  2            [OI]6300_d      1.081      0.30     -80    33
# Comp:  2           [NII]6583_d      11.43      0.30     -80    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -77        31
#  comp.  2:       -75        38
# chi2/DOF: 0.9128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.88      0.23     -77    31
# Comp:  1                Halpha      34.29      0.23     -77    31
# Comp:  2             [SII]6716      7.905      0.24     -75    38
# Comp:  2             [SII]6731      5.262      0.24     -75    38
# Comp:  2              HeII4687    0.08252      0.24     -75    38
# Comp:  2               HeI5876     0.8812      0.24     -75    38
# Comp:  2          [OIII]5007_d      8.386      0.30     -75    38
# Comp:  2            [OI]6300_d     0.9483      0.30     -75    38
# Comp:  2           [NII]6583_d      10.86      0.30     -75    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -75        36
#  comp.  2:       -77        34
# chi2/DOF: 0.9240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.833      0.24     -75    36
# Comp:  1                Halpha      34.65      0.24     -75    36
# Comp:  2             [SII]6716      7.818      0.23     -77    34
# Comp:  2             [SII]6731      5.516      0.23     -77    34
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.989      0.23     -74    32
# Comp:  1                Halpha      33.88      0.23     -74    32
# Comp:  2             [SII]6716      7.344      0.23     -78    24
# Comp:  2             [SII]6731      5.100      0.23     -78    24
# Comp:  2              HeII4687     0.1676      0.23     -78    24
# Comp:  2               HeI5876      1.222      0.23     -78    24
# Comp:  2          [OIII]5007_d      8.030      0.29     -78    24
# Comp:  2            [OI]6300_d     0.9844      0.29     -78    24
# Comp:  2           [NII]6583_d      10.82      0.29     -78    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -76        32
#  comp.  2:       -77        38
# chi2/DOF: 0.9473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.20      0.23     -76    32
# Comp:  1                Halpha      34.18      0.23     -76    32
# Comp:  2             [SII]6716      7.619      0.24     -77    38
# Comp:  2             [SII]6731      5.255      0.24     -77    38
# Comp:  2              HeII4687     0.2613      0.24     -77    38
# Comp:  2               HeI5876      1.122      0.24     -77    38
# Comp:  2          [OIII]5007_d      8.095      0.30     -77    38
# Comp:  2            [OI]6300_d      1.085      0.30     -77    38
# Comp:  2           [NII]6583_d      11.62      0.30     -77    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        13
#  comp.  1:       -75        34
#  comp.  2:       -78        33
# chi2/DOF: 0.9450; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.10      0.23     -75    34
# Comp:  1                Halpha      34.66      0.23     -75    34
# Comp:  2             [SII]6716      7.539      0.23     -78    33
# Comp:  2             [SII]6731      5.323      0.23     -78    33
# Comp:  2              HeII4687      0.000      0.23     -78    33
# Comp:  2               HeI5876      1.368      0.23     -78    33
# Comp:  2          [OIII]5007_d      8.390      0.30     -78    33
# Comp:  2            [OI]6300_d      1.011      0.30     -78    33
# Comp:  2           [NII]6583_d      11.34      0.30     -78    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -75        33
#  comp.  2:       -82        26
# chi2/DOF: 0.9415; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.72      0.23     -75    33
# Comp:  1                Halpha      34.65      0.23     -75    33
# Comp:  2             [SII]6716      7.324      0.23     -82    26
# Comp:  2             [SII]6731      5.306      0.23     -82    26
# Comp:  2              HeII4687      0.000      0.23     -82    26
# Comp:  2               HeI5876      1.122      0.23     -82    26
# Comp:  2          [OIII]5007_d      8.432      0.29     -82    26
# Comp:  2            [OI]6300_d      1.037      0.29     -82    26
# Comp:  2           [NII]6583_d      11.25      0.29     -82    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        32
#  comp.  1:       -78        24
#  comp.  2:       -77        30
# chi2/DOF: 0.9242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.99      0.23     -78    24
# Comp:  1                Halpha      33.32      0.23     -78    24
# Comp:  2             [SII]6716      7.574      0.23     -77    30
# Comp:  2             [SII]6731      5.394      0.23     -77    30
# Comp:  2              HeII4687      0.000      0.23     -77    30
# Comp:  2               HeI5876     0.9400      0.23     -77    30
# Comp:  2          [OIII]5007_d      8.045      0.29     -77    30
# Comp:  2            [OI]6300_d     0.7688      0.29     -77    30
# Comp:  2           [NII]6583_d      11.12      0.29     -77    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        47
#  comp.  1:       -77        24
#  comp.  2:       -79        26
# chi2/DOF: 0.9125; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.23     -77    24
# Comp:  1                Halpha      33.31      0.23     -77    24
# Comp:  2             [SII]6716      7.389      0.23     -79    26
# Comp:  2             [SII]6731      5.277      0.23     -79    26
# Comp:  2              HeII4687      0.000      0.23     -79    26
# Comp:  2               HeI5876      1.221      0.23     -79    26
# Comp:  2          [OIII]5007_d      7.887      0.29     -79    26
# Comp:  2            [OI]6300_d     0.6184      0.29     -79    26
# Comp:  2           [NII]6583_d      11.61      0.29     -79    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -75        28
#  comp.  2:       -80        27
# chi2/DOF: 0.9466; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.07      0.23     -75    28
# Comp:  1                Halpha      33.63      0.23     -75    28
# Comp:  2             [SII]6716      7.216      0.23     -80    27
# Comp:  2             [SII]6731      5.219      0.23     -80    27
# Comp:  2              HeII4687      0.000      0.23     -80    27
# Comp:  2               HeI5876      1.201      0.23     -80    27
# Comp:  2          [OIII]5007_d      7.836      0.29     -80    27
# Comp:  2            [OI]6300_d     0.7672      0.29     -80    27
# Comp:  2           [NII]6583_d      11.18      0.29     -80    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        63
#  comp.  1:       -79        28
#  comp.  2:       -81        30
# chi2/DOF: 0.9313; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.34      0.23     -79    28
# Comp:  1                Halpha      33.82      0.23     -79    28
# Comp:  2             [SII]6716      7.432      0.23     -81    30
# Comp:  2             [SII]6731      5.083      0.23     -81    30
# Comp:  2              HeII4687      0.000      0.23     -81    30
# Comp:  2               HeI5876      1.303      0.23     -81    30
# Comp:  2          [OIII]5007_d      8.608      0.29     -81    30
# Comp:  2            [OI]6300_d     0.8761      0.29     -81    30
# Comp:  2           [NII]6583_d      11.44      0.29     -81    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -78        28
#  comp.  2:       -76        39
# chi2/DOF: 0.9267; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.02      0.23     -78    28
# Comp:  1                Halpha      33.61      0.23     -78    28
# Comp:  2             [SII]6716      7.763      0.24     -76    39
# Comp:  2             [SII]6731      5.550      0.24     -76    39
# Comp:  2              HeII4687      0.000      0.24     -76    39
# Comp:  2               HeI5876      1.233      0.24     -76    39
# Comp:  2          [OIII]5007_d      8.390      0.30     -76    39
# Comp:  2            [OI]6300_d     0.8488      0.30     -76    39
# Comp:  2           [NII]6583_d      11.22      0.30     -76    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        28
#  comp.  1:       -76        34
#  comp.  2:       -78        31
# chi2/DOF: 0.9354; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.85      0.23     -76    34
# Comp:  1                Halpha      34.57      0.23     -76    34
# Comp:  2             [SII]6716      7.562      0.23     -78    31
# Comp:  2             [SII]6731      5.254      0.23     -78    31
# Comp:  2              HeII4687     0.1890      0.23     -78    31
# Comp:  2               HeI5876      1.053      0.23     -78    31
# Comp:  2          [OIII]5007_d      7.860      0.29     -78    31
# Comp:  2            [OI]6300_d      1.024      0.29     -78    31
# Comp:  2           [NII]6583_d      10.62      0.29     -78    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -74        33
#  comp.  2:       -81        26
# chi2/DOF: 0.9352; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.98      0.23     -74    33
# Comp:  1                Halpha      33.90      0.23     -74    33
# Comp:  2             [SII]6716      7.426      0.23     -81    26
# Comp:  2             [SII]6731      5.249      0.23     -81    26
# Comp:  2              HeII4687      0.000      0.23     -81    26
# Comp:  2               HeI5876     0.9736      0.23     -81    26
# Comp:  2          [OIII]5007_d      8.498      0.29     -81    26
# Comp:  2            [OI]6300_d     0.8706      0.29     -81    26
# Comp:  2           [NII]6583_d      11.15      0.29     -81    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -76        23
#  comp.  2:       -78        29
# chi2/DOF: 0.9142; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.68      0.23     -76    23
# Comp:  1                Halpha      32.92      0.23     -76    23
# Comp:  2             [SII]6716      7.607      0.23     -78    29
# Comp:  2             [SII]6731      5.061      0.23     -78    29
# Comp:  2              HeII4687      0.000      0.23     -78    29
# Comp:  2               HeI5876      1.013      0.23     -78    29
# Comp:  2          [OIII]5007_d      7.975      0.29     -78    29
# Comp:  2            [OI]6300_d     0.8712      0.29     -78    29
# Comp:  2           [NII]6583_d      11.44      0.29     -78    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -75        31
#  comp.  2:       -77        28
# chi2/DOF: 0.9384; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.62      0.23     -75    31
# Comp:  1                Halpha      33.78      0.23     -75    31
# Comp:  2             [SII]6716      7.362      0.23     -77    28
# Comp:  2             [SII]6731      4.990      0.23     -77    28
# Comp:  2              HeII4687     0.1279      0.23     -77    28
# Comp:  2               HeI5876     0.8952      0.23     -77    28
# Comp:  2          [OIII]5007_d      7.963      0.29     -77    28
# Comp:  2            [OI]6300_d      1.164      0.29     -77    28
# Comp:  2           [NII]6583_d      10.60      0.29     -77    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -76        34
#  comp.  2:       -78        31
# chi2/DOF: 0.9375; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.65      0.23     -76    34
# Comp:  1                Halpha      34.70      0.23     -76    34
# Comp:  2             [SII]6716      7.773      0.23     -78    31
# Comp:  2             [SII]6731      5.366      0.23     -78    31
# Comp:  2              HeII4687      0.000      0.23     -78    31
# Comp:  2               HeI5876      1.197      0.23     -78    31
# Comp:  2          [OIII]5007_d      8.571      0.29     -78    31
# Comp:  2            [OI]6300_d      1.213      0.29     -78    31
# Comp:  2           [NII]6583_d      11.20      0.29     -78    31
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.12793792, 0.69184706, 0.27645267, 0.24831306, 0.08016489,
#        0.16181974, 0.34220447, 0.22990166, 0.43080752])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([11.03046749, 46.06941128, 10.52287876,  7.28755274,  0.        ,
#         1.39997787,  8.69865022,  1.22688246, 15.39786575])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_11_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_11", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_11_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_11_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_11_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.492215    0.050332
# 1        Halpha  2.055765    0.030872
# 2     [SII]6716  0.469565    0.012336
# 3     [SII]6731  0.325194    0.011081
# 4      HeII4687  0.000000    0.003577
# 5       HeI5876  0.062472    0.007221
# 6  [OIII]5007_d  0.388162    0.015270
# 7    [OI]6300_d  0.054747    0.010259
# 8   [NII]6583_d  0.687102    0.019224
#           Name      Flux  Error_flux
# 0        Hbeta  0.492215    0.050332
# 1       Halpha  2.055765    0.030872
# 2    [SII]6716  0.469565    0.012336
# 3    [SII]6731  0.325194    0.011081
# 4     HeII4687  0.000000    0.003577
# 5      HeI5876  0.062472    0.007221
# 6   [OIII]4959  0.097040    0.015270
# 7   [OIII]5007  0.291121    0.015270
# 8     [OI]6300  0.041061    0.010259
# 9     [OI]6364  0.013687    0.010259
# 10   [NII]6548  0.171776    0.019224
# 11   [NII]6583  0.515327    0.019224

# %%
np.median(flux_rf_rebin)
# Out:
# 0.044623219100696554
