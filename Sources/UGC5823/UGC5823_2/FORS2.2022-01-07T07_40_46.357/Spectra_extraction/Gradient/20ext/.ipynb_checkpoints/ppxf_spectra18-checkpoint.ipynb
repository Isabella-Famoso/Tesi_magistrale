# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_18.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_18']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.04454845 0.04442409 0.03767682 ... 0.01963174 0.02119582 0.02100618] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -299       240
# chi2/DOF: 0.01977; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
# chi2/DOF: 0.01396; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-57.58366683,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:     -1748         1
#  comp.  1:       -55        33
#  comp.  2:       -56        39
# chi2/DOF: 0.8030; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.79      0.34     -55    33
# Comp:  1                Halpha      42.70      0.34     -55    33
# Comp:  2             [SII]6716      9.792      0.35     -56    39
# Comp:  2             [SII]6731      6.394      0.35     -56    39
# Comp:  2              HeII4687      0.000      0.35     -56    39
# Comp:  2               HeI5876      1.942      0.35     -56    39
# Comp:  2          [OIII]5007_d      37.65      0.44     -56    39
# Comp:  2            [OI]6300_d      2.177      0.44     -56    39
# Comp:  2           [NII]6583_d      10.69      0.44     -56    39
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:     -3695         1
#  comp.  1:       -53        19
#  comp.  2:       -54        21
# chi2/DOF: 0.7406; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 59; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.27      0.33     -53    19
# Comp:  1                Halpha      40.81      0.33     -53    19
# Comp:  2             [SII]6716      8.610      0.33     -54    21
# Comp:  2             [SII]6731      6.219      0.33     -54    21
# Comp:  2              HeII4687     0.1147      0.33     -54    21
# Comp:  2               HeI5876      1.807      0.33     -54    21
# Comp:  2          [OIII]5007_d      35.59      0.42     -54    21
# Comp:  2            [OI]6300_d      2.139      0.42     -54    21
# Comp:  2           [NII]6583_d      9.836      0.42     -54    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       108       207
#  comp.  1:       -56        28
#  comp.  2:       -56        27
# chi2/DOF: 0.7428; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.45      0.34     -56    28
# Comp:  1                Halpha      42.41      0.34     -56    28
# Comp:  2             [SII]6716      8.687      0.34     -56    27
# Comp:  2             [SII]6731      5.943      0.34     -56    27
# Comp:  2              HeII4687    0.04448      0.34     -56    27
# Comp:  2               HeI5876      1.574      0.34     -56    27
# Comp:  2          [OIII]5007_d      34.05      0.43     -56    27
# Comp:  2            [OI]6300_d      2.506      0.43     -56    27
# Comp:  2           [NII]6583_d      10.73      0.43     -56    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1748         1
#  comp.  1:       -55        29
#  comp.  2:       -58        30
# chi2/DOF: 0.7840; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.34      0.34     -55    29
# Comp:  1                Halpha      41.66      0.34     -55    29
# Comp:  2             [SII]6716      9.304      0.34     -58    30
# Comp:  2             [SII]6731      6.182      0.34     -58    30
# Comp:  2              HeII4687      0.000      0.34     -58    30
# Comp:  2               HeI5876      1.640      0.34     -58    30
# Comp:  2          [OIII]5007_d      36.64      0.43     -58    30
# Comp:  2            [OI]6300_d      2.120      0.43     -58    30
# Comp:  2           [NII]6583_d      10.09      0.43     -58    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       252         1
#  comp.  1:       -56        42
#  comp.  2:       -58        40
# chi2/DOF: 0.7589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.47      0.35     -56    42
# Comp:  1                Halpha      44.59      0.35     -56    42
# Comp:  2             [SII]6716      9.880      0.35     -58    40
# Comp:  2             [SII]6731      6.617      0.35     -58    40
# Comp:  2              HeII4687      0.000      0.35     -58    40
# Comp:  2               HeI5876      2.167      0.35     -58    40
# Comp:  2          [OIII]5007_d      36.02      0.44     -58    40
# Comp:  2            [OI]6300_d      2.448      0.44     -58    40
# Comp:  2           [NII]6583_d      10.73      0.44     -58    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1807         1
#  comp.  1:       -57        28
#  comp.  2:       -53        42
# chi2/DOF: 0.7764; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.37      0.34     -57    28
# Comp:  1                Halpha      42.27      0.34     -57    28
# Comp:  2             [SII]6716      8.977      0.35     -53    42
# Comp:  2             [SII]6731      6.219      0.35     -53    42
# Comp:  2              HeII4687     0.1673      0.35     -53    42
# Comp:  2               HeI5876      1.862      0.35     -53    42
# Comp:  2          [OIII]5007_d      39.07      0.45     -53    42
# Comp:  2            [OI]6300_d      2.577      0.45     -53    42
# Comp:  2           [NII]6583_d      11.30      0.45     -53    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1687         1
#  comp.  1:       -56        36
#  comp.  2:       -57        35
# chi2/DOF: 0.7810; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.44      0.35     -56    36
# Comp:  1                Halpha      43.52      0.35     -56    36
# Comp:  2             [SII]6716      10.33      0.35     -57    35
# Comp:  2             [SII]6731      5.944      0.35     -57    35
# Comp:  2              HeII4687     0.2391      0.35     -57    35
# Comp:  2               HeI5876      1.849      0.35     -57    35
# Comp:  2          [OIII]5007_d      36.27      0.44     -57    35
# Comp:  2            [OI]6300_d      2.225      0.44     -57    35
# Comp:  2           [NII]6583_d      10.92      0.44     -57    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -302       243
#  comp.  1:       -58        27
#  comp.  2:       -53        42
# chi2/DOF: 0.7742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.89      0.34     -58    27
# Comp:  1                Halpha      41.90      0.34     -58    27
# Comp:  2             [SII]6716      9.865      0.35     -53    42
# Comp:  2             [SII]6731      6.634      0.35     -53    42
# Comp:  2              HeII4687      0.000      0.35     -53    42
# Comp:  2               HeI5876      1.773      0.35     -53    42
# Comp:  2          [OIII]5007_d      39.19      0.45     -53    42
# Comp:  2            [OI]6300_d      1.997      0.45     -53    42
# Comp:  2           [NII]6583_d      10.74      0.45     -53    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1772         1
#  comp.  1:       -53        36
#  comp.  2:       -59        42
# chi2/DOF: 0.7746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.26      0.35     -53    36
# Comp:  1                Halpha      43.78      0.35     -53    36
# Comp:  2             [SII]6716      10.58      0.35     -59    42
# Comp:  2             [SII]6731      6.127      0.35     -59    42
# Comp:  2              HeII4687      0.000      0.35     -59    42
# Comp:  2               HeI5876      2.023      0.35     -59    42
# Comp:  2          [OIII]5007_d      38.74      0.45     -59    42
# Comp:  2            [OI]6300_d      2.772      0.45     -59    42
# Comp:  2           [NII]6583_d      10.63      0.45     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1997         1
#  comp.  1:       -49        36
#  comp.  2:       -57        37
# chi2/DOF: 0.7671; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 82; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.49      0.35     -49    36
# Comp:  1                Halpha      43.42      0.35     -49    36
# Comp:  2             [SII]6716      8.942      0.35     -57    37
# Comp:  2             [SII]6731      6.113      0.35     -57    37
# Comp:  2              HeII4687     0.1294      0.35     -57    37
# Comp:  2               HeI5876      1.862      0.35     -57    37
# Comp:  2          [OIII]5007_d      36.40      0.44     -57    37
# Comp:  2            [OI]6300_d      2.272      0.44     -57    37
# Comp:  2           [NII]6583_d      10.84      0.44     -57    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1360         1
#  comp.  1:       -56        27
#  comp.  2:       -57        27
# chi2/DOF: 0.7596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.37      0.34     -56    27
# Comp:  1                Halpha      41.79      0.34     -56    27
# Comp:  2             [SII]6716      10.13      0.34     -57    27
# Comp:  2             [SII]6731      6.029      0.34     -57    27
# Comp:  2              HeII4687     0.1324      0.34     -57    27
# Comp:  2               HeI5876      1.851      0.34     -57    27
# Comp:  2          [OIII]5007_d      34.18      0.43     -57    27
# Comp:  2            [OI]6300_d      1.671      0.43     -57    27
# Comp:  2           [NII]6583_d      10.29      0.43     -57    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1794       373
#  comp.  1:       -51        36
#  comp.  2:       -61        30
# chi2/DOF: 0.7511; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.78      0.35     -51    36
# Comp:  1                Halpha      43.00      0.35     -51    36
# Comp:  2             [SII]6716      8.647      0.34     -61    30
# Comp:  2             [SII]6731      6.712      0.34     -61    30
# Comp:  2              HeII4687      0.000      0.34     -61    30
# Comp:  2               HeI5876      1.752      0.34     -61    30
# Comp:  2          [OIII]5007_d      35.82      0.43     -61    30
# Comp:  2            [OI]6300_d      1.626      0.43     -61    30
# Comp:  2           [NII]6583_d      10.07      0.43     -61    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1737       944
#  comp.  1:       -54        30
#  comp.  2:       -55        45
# chi2/DOF: 0.7816; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.32      0.34     -54    30
# Comp:  1                Halpha      41.95      0.34     -54    30
# Comp:  2             [SII]6716      9.987      0.36     -55    45
# Comp:  2             [SII]6731      6.509      0.36     -55    45
# Comp:  2              HeII4687     0.5329      0.36     -55    45
# Comp:  2               HeI5876      1.994      0.36     -55    45
# Comp:  2          [OIII]5007_d      38.21      0.45     -55    45
# Comp:  2            [OI]6300_d      2.545      0.45     -55    45
# Comp:  2           [NII]6583_d      10.95      0.45     -55    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1683      1000
#  comp.  1:       -58        29
#  comp.  2:       -56        37
# chi2/DOF: 0.7725; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.58      0.34     -58    29
# Comp:  1                Halpha      42.15      0.34     -58    29
# Comp:  2             [SII]6716      9.786      0.35     -56    37
# Comp:  2             [SII]6731      6.124      0.35     -56    37
# Comp:  2              HeII4687     0.5021      0.35     -56    37
# Comp:  2               HeI5876      1.863      0.35     -56    37
# Comp:  2          [OIII]5007_d      37.20      0.44     -56    37
# Comp:  2            [OI]6300_d      2.205      0.44     -56    37
# Comp:  2           [NII]6583_d      10.90      0.44     -56    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -618       326
#  comp.  1:       -54        34
#  comp.  2:       -55        16
# chi2/DOF: 0.7514; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.39      0.34     -54    34
# Comp:  1                Halpha      43.11      0.34     -54    34
# Comp:  2             [SII]6716      9.203      0.33     -55    16
# Comp:  2             [SII]6731      5.467      0.33     -55    16
# Comp:  2              HeII4687      0.000      0.33     -55    16
# Comp:  2               HeI5876      1.683      0.33     -55    16
# Comp:  2          [OIII]5007_d      35.33      0.42     -55    16
# Comp:  2            [OI]6300_d      2.405      0.42     -55    16
# Comp:  2           [NII]6583_d      10.20      0.42     -55    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1852         1
#  comp.  1:       -53        40
#  comp.  2:       -56        38
# chi2/DOF: 0.7837; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.77      0.35     -53    40
# Comp:  1                Halpha      43.84      0.35     -53    40
# Comp:  2             [SII]6716      9.747      0.35     -56    38
# Comp:  2             [SII]6731      6.528      0.35     -56    38
# Comp:  2              HeII4687     0.4401      0.35     -56    38
# Comp:  2               HeI5876      1.941      0.35     -56    38
# Comp:  2          [OIII]5007_d      38.50      0.44     -56    38
# Comp:  2            [OI]6300_d      2.295      0.44     -56    38
# Comp:  2           [NII]6583_d      10.86      0.44     -56    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1851         1
#  comp.  1:       -56        31
#  comp.  2:       -59        33
# chi2/DOF: 0.7773; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.43      0.34     -56    31
# Comp:  1                Halpha      42.02      0.34     -56    31
# Comp:  2             [SII]6716      9.469      0.34     -59    33
# Comp:  2             [SII]6731      6.219      0.34     -59    33
# Comp:  2              HeII4687     0.2107      0.34     -59    33
# Comp:  2               HeI5876      1.981      0.34     -59    33
# Comp:  2          [OIII]5007_d      37.01      0.43     -59    33
# Comp:  2            [OI]6300_d      2.595      0.43     -59    33
# Comp:  2           [NII]6583_d      10.31      0.43     -59    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2031       449
#  comp.  1:       -55        43
#  comp.  2:       -60        39
# chi2/DOF: 0.7397; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.23      0.35     -55    43
# Comp:  1                Halpha      44.59      0.35     -55    43
# Comp:  2             [SII]6716      10.53      0.35     -60    39
# Comp:  2             [SII]6731      5.788      0.35     -60    39
# Comp:  2              HeII4687      0.000      0.35     -60    39
# Comp:  2               HeI5876      1.912      0.35     -60    39
# Comp:  2          [OIII]5007_d      39.30      0.44     -60    39
# Comp:  2            [OI]6300_d      2.380      0.44     -60    39
# Comp:  2           [NII]6583_d      10.57      0.44     -60    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -3364       342
#  comp.  1:       -54        40
#  comp.  2:       -53        43
# chi2/DOF: 0.7727; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.93      0.35     -54    40
# Comp:  1                Halpha      44.09      0.35     -54    40
# Comp:  2             [SII]6716      10.85      0.35     -53    43
# Comp:  2             [SII]6731      6.222      0.35     -53    43
# Comp:  2              HeII4687     0.2404      0.35     -53    43
# Comp:  2               HeI5876      2.125      0.35     -53    43
# Comp:  2          [OIII]5007_d      39.96      0.45     -53    43
# Comp:  2            [OI]6300_d      2.367      0.45     -53    43
# Comp:  2           [NII]6583_d      10.61      0.45     -53    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1586      1000
#  comp.  1:       -55        43
#  comp.  2:       -53        48
# chi2/DOF: 0.7380; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.35      0.35     -55    43
# Comp:  1                Halpha      44.45      0.35     -55    43
# Comp:  2             [SII]6716      11.04      0.36     -53    48
# Comp:  2             [SII]6731      6.590      0.36     -53    48
# Comp:  2              HeII4687     0.4638      0.36     -53    48
# Comp:  2               HeI5876      1.617      0.36     -53    48
# Comp:  2          [OIII]5007_d      37.93      0.46     -53    48
# Comp:  2            [OI]6300_d      2.308      0.46     -53    48
# Comp:  2           [NII]6583_d      10.98      0.46     -53    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1704         1
#  comp.  1:       -51        41
#  comp.  2:       -53        43
# chi2/DOF: 0.7520; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.31      0.35     -51    41
# Comp:  1                Halpha      44.51      0.35     -51    41
# Comp:  2             [SII]6716      10.70      0.35     -53    43
# Comp:  2             [SII]6731      6.930      0.35     -53    43
# Comp:  2              HeII4687      0.000      0.35     -53    43
# Comp:  2               HeI5876      2.169      0.35     -53    43
# Comp:  2          [OIII]5007_d      40.21      0.45     -53    43
# Comp:  2            [OI]6300_d      2.102      0.45     -53    43
# Comp:  2           [NII]6583_d      11.04      0.45     -53    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1748         1
#  comp.  1:       -52        27
#  comp.  2:       -60        28
# chi2/DOF: 0.7652; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.20      0.34     -52    27
# Comp:  1                Halpha      41.50      0.34     -52    27
# Comp:  2             [SII]6716      9.263      0.34     -60    28
# Comp:  2             [SII]6731      6.241      0.34     -60    28
# Comp:  2              HeII4687      0.000      0.34     -60    28
# Comp:  2               HeI5876      1.817      0.34     -60    28
# Comp:  2          [OIII]5007_d      36.67      0.43     -60    28
# Comp:  2            [OI]6300_d      2.540      0.43     -60    28
# Comp:  2           [NII]6583_d      10.61      0.43     -60    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2749       449
#  comp.  1:       -56        29
#  comp.  2:       -51        44
# chi2/DOF: 0.7635; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.78      0.34     -56    29
# Comp:  1                Halpha      41.87      0.34     -56    29
# Comp:  2             [SII]6716      9.981      0.35     -51    44
# Comp:  2             [SII]6731      6.752      0.35     -51    44
# Comp:  2              HeII4687      0.000      0.35     -51    44
# Comp:  2               HeI5876      1.894      0.35     -51    44
# Comp:  2          [OIII]5007_d      40.44      0.45     -51    44
# Comp:  2            [OI]6300_d      1.981      0.45     -51    44
# Comp:  2           [NII]6583_d      10.66      0.45     -51    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1767         1
#  comp.  1:       -54        38
#  comp.  2:       -54        44
# chi2/DOF: 0.7800; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.43      0.35     -54    38
# Comp:  1                Halpha      43.41      0.35     -54    38
# Comp:  2             [SII]6716      9.847      0.36     -54    44
# Comp:  2             [SII]6731      5.896      0.36     -54    44
# Comp:  2              HeII4687     0.2045      0.36     -54    44
# Comp:  2               HeI5876      1.946      0.36     -54    44
# Comp:  2          [OIII]5007_d      39.22      0.45     -54    44
# Comp:  2            [OI]6300_d      2.153      0.45     -54    44
# Comp:  2           [NII]6583_d      10.65      0.45     -54    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2160       927
#  comp.  1:       -57        34
#  comp.  2:       -58        48
# chi2/DOF: 0.7710; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.09      0.34     -57    34
# Comp:  1                Halpha      42.75      0.34     -57    34
# Comp:  2             [SII]6716      9.982      0.36     -58    48
# Comp:  2             [SII]6731      6.601      0.36     -58    48
# Comp:  2              HeII4687      0.000      0.36     -58    48
# Comp:  2               HeI5876      1.993      0.36     -58    48
# Comp:  2          [OIII]5007_d      40.25      0.46     -58    48
# Comp:  2            [OI]6300_d      2.495      0.46     -58    48
# Comp:  2           [NII]6583_d      11.09      0.46     -58    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1710       546
#  comp.  1:       -55        38
#  comp.  2:       -53        28
# chi2/DOF: 0.7730; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.38      0.35     -55    38
# Comp:  1                Halpha      43.53      0.35     -55    38
# Comp:  2             [SII]6716      10.21      0.34     -53    28
# Comp:  2             [SII]6731      6.225      0.34     -53    28
# Comp:  2              HeII4687      0.000      0.34     -53    28
# Comp:  2               HeI5876      2.097      0.34     -53    28
# Comp:  2          [OIII]5007_d      36.49      0.43     -53    28
# Comp:  2            [OI]6300_d      2.452      0.43     -53    28
# Comp:  2           [NII]6583_d      10.63      0.43     -53    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1717         1
#  comp.  1:       -55        28
#  comp.  2:       -54        29
# chi2/DOF: 0.7780; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.11      0.34     -55    28
# Comp:  1                Halpha      41.86      0.34     -55    28
# Comp:  2             [SII]6716      10.16      0.34     -54    29
# Comp:  2             [SII]6731      5.948      0.34     -54    29
# Comp:  2              HeII4687     0.1316      0.34     -54    29
# Comp:  2               HeI5876      1.830      0.34     -54    29
# Comp:  2          [OIII]5007_d      35.24      0.43     -54    29
# Comp:  2            [OI]6300_d      2.147      0.43     -54    29
# Comp:  2           [NII]6583_d      10.79      0.43     -54    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1743         1
#  comp.  1:       -54        38
#  comp.  2:       -59        35
# chi2/DOF: 0.7718; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.02      0.35     -54    38
# Comp:  1                Halpha      43.68      0.35     -54    38
# Comp:  2             [SII]6716      8.865      0.35     -59    35
# Comp:  2             [SII]6731      6.523      0.35     -59    35
# Comp:  2              HeII4687      0.000      0.35     -59    35
# Comp:  2               HeI5876      1.840      0.35     -59    35
# Comp:  2          [OIII]5007_d      35.35      0.44     -59    35
# Comp:  2            [OI]6300_d      2.271      0.44     -59    35
# Comp:  2           [NII]6583_d      10.23      0.44     -59    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1825      1000
#  comp.  1:       -51        36
#  comp.  2:       -49        39
# chi2/DOF: 0.7598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.92      0.35     -51    36
# Comp:  1                Halpha      42.98      0.35     -51    36
# Comp:  2             [SII]6716      9.643      0.35     -49    39
# Comp:  2             [SII]6731      6.218      0.35     -49    39
# Comp:  2              HeII4687     0.2520      0.35     -49    39
# Comp:  2               HeI5876      1.944      0.35     -49    39
# Comp:  2          [OIII]5007_d      37.47      0.44     -49    39
# Comp:  2            [OI]6300_d      2.102      0.44     -49    39
# Comp:  2           [NII]6583_d      10.61      0.44     -49    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1748         1
#  comp.  1:       -58        35
#  comp.  2:       -58        36
# chi2/DOF: 0.7803; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.68      0.34     -58    35
# Comp:  1                Halpha      43.36      0.34     -58    35
# Comp:  2             [SII]6716      9.633      0.35     -58    36
# Comp:  2             [SII]6731      6.912      0.35     -58    36
# Comp:  2              HeII4687     0.5057      0.35     -58    36
# Comp:  2               HeI5876      1.608      0.35     -58    36
# Comp:  2          [OIII]5007_d      35.97      0.44     -58    36
# Comp:  2            [OI]6300_d      2.253      0.44     -58    36
# Comp:  2           [NII]6583_d      10.13      0.44     -58    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2777       483
#  comp.  1:       -55        30
#  comp.  2:       -62        37
# chi2/DOF: 0.7681; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.33      0.34     -55    30
# Comp:  1                Halpha      42.08      0.34     -55    30
# Comp:  2             [SII]6716      9.908      0.35     -62    37
# Comp:  2             [SII]6731      6.633      0.35     -62    37
# Comp:  2              HeII4687      0.000      0.35     -62    37
# Comp:  2               HeI5876      1.711      0.35     -62    37
# Comp:  2          [OIII]5007_d      38.81      0.44     -62    37
# Comp:  2            [OI]6300_d      2.337      0.44     -62    37
# Comp:  2           [NII]6583_d      10.24      0.44     -62    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       252       234
#  comp.  1:       -55        32
#  comp.  2:       -53        47
# chi2/DOF: 0.7637; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.31      0.34     -55    32
# Comp:  1                Halpha      42.25      0.34     -55    32
# Comp:  2             [SII]6716      11.02      0.36     -53    47
# Comp:  2             [SII]6731      6.839      0.36     -53    47
# Comp:  2              HeII4687      0.000      0.36     -53    47
# Comp:  2               HeI5876      1.892      0.36     -53    47
# Comp:  2          [OIII]5007_d      38.88      0.45     -53    47
# Comp:  2            [OI]6300_d      2.029      0.45     -53    47
# Comp:  2           [NII]6583_d      10.64      0.45     -53    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -899       408
#  comp.  1:       -57        36
#  comp.  2:       -53        43
# chi2/DOF: 0.7766; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.42      0.35     -57    36
# Comp:  1                Halpha      43.52      0.35     -57    36
# Comp:  2             [SII]6716      10.72      0.35     -53    43
# Comp:  2             [SII]6731      5.811      0.35     -53    43
# Comp:  2              HeII4687      0.000      0.35     -53    43
# Comp:  2               HeI5876      2.167      0.35     -53    43
# Comp:  2          [OIII]5007_d      38.86      0.45     -53    43
# Comp:  2            [OI]6300_d      2.072      0.45     -53    43
# Comp:  2           [NII]6583_d      10.74      0.45     -53    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2628       463
#  comp.  1:       -52        34
#  comp.  2:       -57        49
# chi2/DOF: 0.7675; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.17      0.34     -52    34
# Comp:  1                Halpha      42.96      0.34     -52    34
# Comp:  2             [SII]6716      10.10      0.36     -57    49
# Comp:  2             [SII]6731      6.586      0.36     -57    49
# Comp:  2              HeII4687      0.000      0.36     -57    49
# Comp:  2               HeI5876      2.018      0.36     -57    49
# Comp:  2          [OIII]5007_d      39.12      0.46     -57    49
# Comp:  2            [OI]6300_d      2.448      0.46     -57    49
# Comp:  2           [NII]6583_d      10.76      0.46     -57    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1757         1
#  comp.  1:       -57        23
#  comp.  2:       -59        49
# chi2/DOF: 0.7655; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.29      0.33     -57    23
# Comp:  1                Halpha      41.57      0.33     -57    23
# Comp:  2             [SII]6716      10.14      0.36     -59    49
# Comp:  2             [SII]6731      6.574      0.36     -59    49
# Comp:  2              HeII4687      0.000      0.36     -59    49
# Comp:  2               HeI5876      1.846      0.36     -59    49
# Comp:  2          [OIII]5007_d      40.79      0.46     -59    49
# Comp:  2            [OI]6300_d      2.377      0.46     -59    49
# Comp:  2           [NII]6583_d      11.13      0.46     -59    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1847      1000
#  comp.  1:       -54        33
#  comp.  2:       -53        37
# chi2/DOF: 0.7919; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.90      0.34     -54    33
# Comp:  1                Halpha      42.23      0.34     -54    33
# Comp:  2             [SII]6716      9.070      0.35     -53    37
# Comp:  2             [SII]6731      6.142      0.35     -53    37
# Comp:  2              HeII4687     0.5232      0.35     -53    37
# Comp:  2               HeI5876      1.887      0.35     -53    37
# Comp:  2          [OIII]5007_d      36.78      0.44     -53    37
# Comp:  2            [OI]6300_d      2.552      0.44     -53    37
# Comp:  2           [NII]6583_d      10.61      0.44     -53    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1747         1
#  comp.  1:       -58        22
#  comp.  2:       -56        27
# chi2/DOF: 0.7473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.73      0.33     -58    22
# Comp:  1                Halpha      41.44      0.33     -58    22
# Comp:  2             [SII]6716      10.04      0.34     -56    27
# Comp:  2             [SII]6731      5.686      0.34     -56    27
# Comp:  2              HeII4687      0.000      0.34     -56    27
# Comp:  2               HeI5876      2.076      0.34     -56    27
# Comp:  2          [OIII]5007_d      33.96      0.43     -56    27
# Comp:  2            [OI]6300_d      2.190      0.43     -56    27
# Comp:  2           [NII]6583_d      10.33      0.43     -56    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1748         1
#  comp.  1:       -57        34
#  comp.  2:       -60        34
# chi2/DOF: 0.7604; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      27.32      0.34     -57    34
# Comp:  1                Halpha      42.98      0.34     -57    34
# Comp:  2             [SII]6716      8.752      0.34     -60    34
# Comp:  2             [SII]6731      6.176      0.34     -60    34
# Comp:  2              HeII4687     0.1671      0.34     -60    34
# Comp:  2               HeI5876      1.755      0.34     -60    34
# Comp:  2          [OIII]5007_d      35.94      0.43     -60    34
# Comp:  2            [OI]6300_d      2.283      0.43     -60    34
# Comp:  2           [NII]6583_d      10.33      0.43     -60    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1230       394
#  comp.  1:       -50        39
#  comp.  2:       -57        47
# chi2/DOF: 0.7509; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.79      0.35     -50    39
# Comp:  1                Halpha      43.37      0.35     -50    39
# Comp:  2             [SII]6716      11.03      0.36     -57    47
# Comp:  2             [SII]6731      6.189      0.36     -57    47
# Comp:  2              HeII4687      0.000      0.36     -57    47
# Comp:  2               HeI5876      2.471      0.36     -57    47
# Comp:  2          [OIII]5007_d      41.16      0.45     -57    47
# Comp:  2            [OI]6300_d      1.828      0.45     -57    47
# Comp:  2           [NII]6583_d      11.37      0.45     -57    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1616       896
#  comp.  1:       -54        26
#  comp.  2:       -58        32
# chi2/DOF: 0.7707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.69      0.34     -54    26
# Comp:  1                Halpha      42.03      0.34     -54    26
# Comp:  2             [SII]6716      10.27      0.34     -58    32
# Comp:  2             [SII]6731      6.086      0.34     -58    32
# Comp:  2              HeII4687      0.000      0.34     -58    32
# Comp:  2               HeI5876      1.947      0.34     -58    32
# Comp:  2          [OIII]5007_d      36.48      0.43     -58    32
# Comp:  2            [OI]6300_d      2.300      0.43     -58    32
# Comp:  2           [NII]6583_d      10.16      0.43     -58    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       136       127
#  comp.  1:       -54        24
#  comp.  2:       -58        32
# chi2/DOF: 0.7530; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      22.36      0.33     -54    24
# Comp:  1                Halpha      41.53      0.33     -54    24
# Comp:  2             [SII]6716      9.616      0.34     -58    32
# Comp:  2             [SII]6731      6.249      0.34     -58    32
# Comp:  2              HeII4687     0.1707      0.34     -58    32
# Comp:  2               HeI5876      1.948      0.34     -58    32
# Comp:  2          [OIII]5007_d      37.05      0.43     -58    32
# Comp:  2            [OI]6300_d      2.036      0.43     -58    32
# Comp:  2           [NII]6583_d      10.79      0.43     -58    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       252      1000
#  comp.  1:       -55        30
#  comp.  2:       -56        54
# chi2/DOF: 0.7666; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.52      0.34     -55    30
# Comp:  1                Halpha      41.97      0.34     -55    30
# Comp:  2             [SII]6716      9.526      0.37     -56    54
# Comp:  2             [SII]6731      6.529      0.37     -56    54
# Comp:  2              HeII4687     0.2030      0.37     -56    54
# Comp:  2               HeI5876      2.277      0.37     -56    54
# Comp:  2          [OIII]5007_d      41.21      0.46     -56    54
# Comp:  2            [OI]6300_d      2.333      0.46     -56    54
# Comp:  2           [NII]6583_d      10.95      0.46     -56    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1200       705
#  comp.  1:       -54        28
#  comp.  2:       -61        29
# chi2/DOF: 0.7784; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.04      0.34     -54    28
# Comp:  1                Halpha      41.76      0.34     -54    28
# Comp:  2             [SII]6716      9.447      0.34     -61    29
# Comp:  2             [SII]6731      6.072      0.34     -61    29
# Comp:  2              HeII4687      0.000      0.34     -61    29
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.06      0.34     -51    32
# Comp:  1                Halpha      42.92      0.34     -51    32
# Comp:  2             [SII]6716      8.683      0.34     -58    25
# Comp:  2             [SII]6731      6.082      0.34     -58    25
# Comp:  2              HeII4687      0.000      0.34     -58    25
# Comp:  2               HeI5876      1.971      0.34     -58    25
# Comp:  2          [OIII]5007_d      37.13      0.42     -58    25
# Comp:  2            [OI]6300_d      2.298      0.42     -58    25
# Comp:  2           [NII]6583_d      10.35      0.42     -58    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1770         1
#  comp.  1:       -55        38
#  comp.  2:       -48        39
# chi2/DOF: 0.7677; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.72      0.35     -55    38
# Comp:  1                Halpha      43.87      0.35     -55    38
# Comp:  2             [SII]6716      9.615      0.35     -48    39
# Comp:  2             [SII]6731      6.127      0.35     -48    39
# Comp:  2              HeII4687      0.000      0.35     -48    39
# Comp:  2               HeI5876      1.887      0.35     -48    39
# Comp:  2          [OIII]5007_d      38.41      0.44     -48    39
# Comp:  2            [OI]6300_d      2.489      0.44     -48    39
# Comp:  2           [NII]6583_d      10.51      0.44     -48    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2055      1000
#  comp.  1:       -54        27
#  comp.  2:       -54        48
# chi2/DOF: 0.7776; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.29      0.34     -54    27
# Comp:  1                Halpha      42.33      0.34     -54    27
# Comp:  2             [SII]6716      9.423      0.36     -54    48
# Comp:  2             [SII]6731      6.828      0.36     -54    48
# Comp:  2              HeII4687      0.000      0.36     -54    48
# Comp:  2               HeI5876      2.229      0.36     -54    48
# Comp:  2          [OIII]5007_d      39.05      0.45     -54    48
# Comp:  2            [OI]6300_d      2.533      0.45     -54    48
# Comp:  2           [NII]6583_d      10.88      0.45     -54    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1750         1
#  comp.  1:       -55        28
#  comp.  2:       -61        32
# chi2/DOF: 0.7825; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      23.96      0.34     -55    28
# Comp:  1                Halpha      42.31      0.34     -55    28
# Comp:  2             [SII]6716      9.655      0.34     -61    32
# Comp:  2             [SII]6731      6.457      0.34     -61    32
# Comp:  2              HeII4687     0.4498      0.34     -61    32
# Comp:  2               HeI5876      1.940      0.34     -61    32
# Comp:  2          [OIII]5007_d      35.57      0.43     -61    32
# Comp:  2            [OI]6300_d      2.183      0.43     -61    32
# Comp:  2           [NII]6583_d      10.24      0.43     -61    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -473         1
#  comp.  1:       -57        23
#  comp.  2:       -58        34
# chi2/DOF: 0.7676; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.03      0.33     -57    23
# Comp:  1                Halpha      41.35      0.33     -57    23
# Comp:  2             [SII]6716      9.616      0.34     -58    34
# Comp:  2             [SII]6731      6.473      0.34     -58    34
# Comp:  2              HeII4687      0.000      0.34     -58    34
# Comp:  2               HeI5876      1.790      0.34     -58    34
# Comp:  2          [OIII]5007_d      35.82      0.43     -58    34
# Comp:  2            [OI]6300_d      2.103      0.43     -58    34
# Comp:  2           [NII]6583_d      10.56      0.43     -58    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1754         1
#  comp.  1:       -58        26
#  comp.  2:       -56        29
# chi2/DOF: 0.7491; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      25.69      0.34     -58    26
# Comp:  1                Halpha      41.35      0.34     -58    26
# Comp:  2             [SII]6716      8.705      0.34     -56    29
# Comp:  2             [SII]6731      6.543      0.34     -56    29
# Comp:  2              HeII4687      0.000      0.34     -56    29
# Comp:  2               HeI5876      1.915      0.34     -56    29
# Comp:  2          [OIII]5007_d      34.23      0.43     -56    29
# Comp:  2            [OI]6300_d      1.573      0.43     -56    29
# Comp:  2           [NII]6583_d      9.897      0.43     -56    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       227         6
#  comp.  1:       -56        29
#  comp.  2:       -50        38
# chi2/DOF: 0.7781; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.98      0.34     -56    29
# Comp:  1                Halpha      42.14      0.34     -56    29
# Comp:  2             [SII]6716      8.930      0.35     -50    38
# Comp:  2             [SII]6731      6.276      0.35     -50    38
# Comp:  2              HeII4687      0.000      0.35     -50    38
# Comp:  2               HeI5876      1.748      0.35     -50    38
# Comp:  2          [OIII]5007_d      36.84      0.44     -50    38
# Comp:  2            [OI]6300_d      1.748      0.44     -50    38
# Comp:  2           [NII]6583_d      10.16      0.44     -50    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1825         1
#  comp.  1:       -56        34
#  comp.  2:       -64        37
# chi2/DOF: 0.7758; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.98      0.34     -56    34
# Comp:  1                Halpha      42.96      0.34     -56    34
# Comp:  2             [SII]6716      9.862      0.35     -64    37
# Comp:  2             [SII]6731      6.232      0.35     -64    37
# Comp:  2              HeII4687      0.000      0.35     -64    37
# Comp:  2               HeI5876      2.203      0.35     -64    37
# Comp:  2          [OIII]5007_d      37.03      0.44     -64    37
# Comp:  2            [OI]6300_d      2.229      0.44     -64    37
# Comp:  2           [NII]6583_d      10.40      0.44     -64    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2220         1
#  comp.  1:       -58        34
#  comp.  2:       -53        52
# chi2/DOF: 0.7538; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.72      0.34     -58    34
# Comp:  1                Halpha      42.97      0.34     -58    34
# Comp:  2             [SII]6716      10.33      0.37     -53    52
# Comp:  2             [SII]6731      7.160      0.37     -53    52
# Comp:  2              HeII4687      0.000      0.37     -53    52
# Comp:  2               HeI5876      1.982      0.37     -53    52
# Comp:  2          [OIII]5007_d      38.37      0.46     -53    52
# Comp:  2            [OI]6300_d      2.067      0.46     -53    52
# Comp:  2           [NII]6583_d      11.25      0.46     -53    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1790         1
#  comp.  1:       -55        38
#  comp.  2:       -53        32
# chi2/DOF: 0.7785; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.08      0.35     -55    38
# Comp:  1                Halpha      44.07      0.35     -55    38
# Comp:  2             [SII]6716      10.34      0.34     -53    32
# Comp:  2             [SII]6731      6.230      0.34     -53    32
# Comp:  2              HeII4687      0.000      0.34     -53    32
# Comp:  2               HeI5876      1.635      0.34     -53    32
# Comp:  2          [OIII]5007_d      35.77      0.43     -53    32
# Comp:  2            [OI]6300_d      2.331      0.43     -53    32
# Comp:  2           [NII]6583_d      10.39      0.43     -53    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2116      1000
#  comp.  1:       -54        33
#  comp.  2:       -62        24
# chi2/DOF: 0.7680; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      24.95      0.34     -54    33
# Comp:  1                Halpha      42.70      0.34     -54    33
# Comp:  2             [SII]6716      9.408      0.33     -62    24
# Comp:  2             [SII]6731      6.537      0.33     -62    24
# Comp:  2              HeII4687      0.000      0.33     -62    24
# Comp:  2               HeI5876      1.667      0.33     -62    24
# Comp:  2          [OIII]5007_d      36.33      0.42     -62    24
# Comp:  2            [OI]6300_d      2.053      0.42     -62    24
# Comp:  2           [NII]6583_d      9.865      0.42     -62    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1733         1
#  comp.  1:       -57        26
#  comp.  2:       -56        23
# chi2/DOF: 0.7455; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.33      0.34     -57    26
# Comp:  1                Halpha      41.31      0.34     -57    26
# Comp:  2             [SII]6716      9.246      0.33     -56    23
# Comp:  2             [SII]6731      6.101      0.33     -56    23
# Comp:  2              HeII4687      0.000      0.33     -56    23
# Comp:  2               HeI5876      1.527      0.33     -56    23
# Comp:  2          [OIII]5007_d      34.63      0.42     -56    23
# Comp:  2            [OI]6300_d      2.042      0.42     -56    23
# Comp:  2           [NII]6583_d      9.920      0.42     -56    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1969      1000
#  comp.  1:       -56        34
#  comp.  2:       -59        37
# chi2/DOF: 0.7710; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.66      0.34     -56    34
# Comp:  1                Halpha      42.42      0.34     -56    34
# Comp:  2             [SII]6716      9.553      0.35     -59    37
# Comp:  2             [SII]6731      5.940      0.35     -59    37
# Comp:  2              HeII4687     0.2386      0.35     -59    37
# Comp:  2               HeI5876      1.671      0.35     -59    37
# Comp:  2          [OIII]5007_d      35.33      0.44     -59    37
# Comp:  2            [OI]6300_d      2.596      0.44     -59    37
# Comp:  2           [NII]6583_d      10.78      0.44     -59    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1721         1
#  comp.  1:       -56        42
#  comp.  2:       -62        44
# chi2/DOF: 0.7525; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      26.85      0.35     -56    42
# Comp:  1                Halpha      44.68      0.35     -56    42
# Comp:  2             [SII]6716      10.84      0.36     -62    44
# Comp:  2             [SII]6731      7.085      0.36     -62    44
# Comp:  2              HeII4687     0.4616      0.36     -62    44
# Comp:  2               HeI5876      2.052      0.36     -62    44
# Comp:  2          [OIII]5007_d      37.61      0.45     -62    44
# Comp:  2            [OI]6300_d      2.663      0.45     -62    44
# Comp:  2           [NII]6583_d      10.50      0.45     -62    44
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.54449334, 1.31127379, 0.83711326, 0.48722483, 0.16843788,
#        0.21538013, 1.90935675, 0.37247653, 0.53668777])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([25.13129396, 58.45591015, 13.71768343,  8.97646881,  0.        ,
#         2.37970473, 39.32060362,  2.86013606, 14.67243046])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_18_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_18", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_18_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_18_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_18_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.764300    0.046972
# 1        Halpha  1.777779    0.039879
# 2     [SII]6716  0.417186    0.025459
# 3     [SII]6731  0.272995    0.014818
# 4      HeII4687  0.000000    0.005123
# 5       HeI5876  0.072372    0.006550
# 6  [OIII]5007_d  1.195830    0.058068
# 7    [OI]6300_d  0.086983    0.011328
# 8   [NII]6583_d  0.446222    0.016322
#           Name      Flux  Error_flux
# 0        Hbeta  0.764300    0.046972
# 1       Halpha  1.777779    0.039879
# 2    [SII]6716  0.417186    0.025459
# 3    [SII]6731  0.272995    0.014818
# 4     HeII4687  0.000000    0.005123
# 5      HeI5876  0.072372    0.006550
# 6   [OIII]4959  0.298958    0.058068
# 7   [OIII]5007  0.896873    0.058068
# 8     [OI]6300  0.065237    0.011328
# 9     [OI]6364  0.021746    0.011328
# 10   [NII]6548  0.111556    0.016322
# 11   [NII]6583  0.334667    0.016322

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03041230021344357
