# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.05797453 0.06177769 0.04498453 ... 0.04022152 0.04300922 0.04372414] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         6
# chi2/DOF: 0.01209; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
# chi2/DOF: 0.006911; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-66.4132464 ,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -127       149
#  comp.  1:       -81        30
#  comp.  2:       -81        36
# chi2/DOF: 1.283; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.27      0.20     -81    30
# Comp:  1                Halpha      45.07      0.20     -81    30
# Comp:  2             [SII]6716      10.21      0.21     -81    36
# Comp:  2             [SII]6731      7.470      0.21     -81    36
# Comp:  2              HeII4687     0.5369      0.21     -81    36
# Comp:  2               HeI5876      1.962      0.21     -81    36
# Comp:  2          [OIII]5007_d      24.28      0.26     -81    36
# Comp:  2            [OI]6300_d      1.726      0.26     -81    36
# Comp:  2           [NII]6583_d      12.32      0.26     -81    36
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  46.01; gas flux:     12 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  174.1; gas flux:     62 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  38.32; gas flux:     14 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  26.92; gas flux:     10 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.018; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  7.344; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  67.17; gas flux:     25 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.558; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  34.28; gas flux:     17 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       211
#  comp.  1:       -82        31
#  comp.  2:       -87        30
# chi2/DOF: 1.237; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.07      0.20     -82    31
# Comp:  1                Halpha      45.15      0.20     -82    31
# Comp:  2             [SII]6716      10.03      0.20     -87    30
# Comp:  2             [SII]6731      7.891      0.20     -87    30
# Comp:  2              HeII4687     0.5225      0.20     -87    30
# Comp:  2               HeI5876      2.085      0.20     -87    30
# Comp:  2          [OIII]5007_d      24.11      0.26     -87    30
# Comp:  2            [OI]6300_d      1.408      0.26     -87    30
# Comp:  2           [NII]6583_d      12.10      0.26     -87    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119       188
#  comp.  1:       -79        33
#  comp.  2:       -80        36
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.69      0.20     -79    33
# Comp:  1                Halpha      45.45      0.20     -79    33
# Comp:  2             [SII]6716      9.974      0.21     -80    36
# Comp:  2             [SII]6731      6.948      0.21     -80    36
# Comp:  2              HeII4687     0.2573      0.21     -80    36
# Comp:  2               HeI5876      1.867      0.21     -80    36
# Comp:  2          [OIII]5007_d      22.78      0.26     -80    36
# Comp:  2            [OI]6300_d      1.953      0.26     -80    36
# Comp:  2           [NII]6583_d      13.11      0.26     -80    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79       192
#  comp.  1:       -83        30
#  comp.  2:       -77        44
# chi2/DOF: 1.231; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.88      0.20     -83    30
# Comp:  1                Halpha      45.12      0.20     -83    30
# Comp:  2             [SII]6716      10.46      0.21     -77    44
# Comp:  2             [SII]6731      8.352      0.21     -77    44
# Comp:  2              HeII4687     0.5292      0.21     -77    44
# Comp:  2               HeI5876      2.097      0.21     -77    44
# Comp:  2          [OIII]5007_d      23.34      0.27     -77    44
# Comp:  2            [OI]6300_d      1.849      0.27     -77    44
# Comp:  2           [NII]6583_d      12.72      0.27     -77    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94       253
#  comp.  1:       -81        28
#  comp.  2:       -85        28
# chi2/DOF: 1.187; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.770      0.20     -81    28
# Comp:  1                Halpha      44.29      0.20     -81    28
# Comp:  2             [SII]6716      9.765      0.20     -85    28
# Comp:  2             [SII]6731      7.473      0.20     -85    28
# Comp:  2              HeII4687     0.5172      0.20     -85    28
# Comp:  2               HeI5876      1.749      0.20     -85    28
# Comp:  2          [OIII]5007_d      24.08      0.25     -85    28
# Comp:  2            [OI]6300_d      1.469      0.25     -85    28
# Comp:  2           [NII]6583_d      12.06      0.25     -85    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       148
#  comp.  1:       -81        30
#  comp.  2:       -83        28
# chi2/DOF: 1.237; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.68      0.20     -81    30
# Comp:  1                Halpha      45.06      0.20     -81    30
# Comp:  2             [SII]6716      10.06      0.20     -83    28
# Comp:  2             [SII]6731      6.699      0.20     -83    28
# Comp:  2              HeII4687     0.5044      0.20     -83    28
# Comp:  2               HeI5876      1.989      0.20     -83    28
# Comp:  2          [OIII]5007_d      25.20      0.25     -83    28
# Comp:  2            [OI]6300_d      1.751      0.25     -83    28
# Comp:  2           [NII]6583_d      12.31      0.25     -83    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       171
#  comp.  1:       -82        27
#  comp.  2:       -78        48
# chi2/DOF: 1.226; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.46      0.20     -82    27
# Comp:  1                Halpha      44.53      0.20     -82    27
# Comp:  2             [SII]6716      10.96      0.21     -78    48
# Comp:  2             [SII]6731      7.765      0.21     -78    48
# Comp:  2              HeII4687     0.5382      0.21     -78    48
# Comp:  2               HeI5876      2.055      0.21     -78    48
# Comp:  2          [OIII]5007_d      23.84      0.27     -78    48
# Comp:  2            [OI]6300_d      1.978      0.27     -78    48
# Comp:  2           [NII]6583_d      12.35      0.27     -78    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -173       151
#  comp.  1:       -82        28
#  comp.  2:       -83        31
# chi2/DOF: 1.240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.22      0.20     -82    28
# Comp:  1                Halpha      44.37      0.20     -82    28
# Comp:  2             [SII]6716      9.687      0.20     -83    31
# Comp:  2             [SII]6731      8.024      0.20     -83    31
# Comp:  2              HeII4687     0.5242      0.20     -83    31
# Comp:  2               HeI5876      2.057      0.20     -83    31
# Comp:  2          [OIII]5007_d      25.36      0.26     -83    31
# Comp:  2            [OI]6300_d      1.669      0.26     -83    31
# Comp:  2           [NII]6583_d      13.00      0.26     -83    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       174
#  comp.  1:       -80        31
#  comp.  2:       -79        44
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.73      0.20     -80    31
# Comp:  1                Halpha      45.13      0.20     -80    31
# Comp:  2             [SII]6716      10.60      0.21     -79    44
# Comp:  2             [SII]6731      7.821      0.21     -79    44
# Comp:  2              HeII4687     0.5963      0.21     -79    44
# Comp:  2               HeI5876      1.916      0.21     -79    44
# Comp:  2          [OIII]5007_d      23.48      0.27     -79    44
# Comp:  2            [OI]6300_d      1.986      0.27     -79    44
# Comp:  2           [NII]6583_d      12.50      0.27     -79    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78       131
#  comp.  1:       -81        28
#  comp.  2:       -80        38
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.28      0.20     -81    28
# Comp:  1                Halpha      44.51      0.20     -81    28
# Comp:  2             [SII]6716      10.53      0.21     -80    38
# Comp:  2             [SII]6731      7.460      0.21     -80    38
# Comp:  2              HeII4687     0.7248      0.21     -80    38
# Comp:  2               HeI5876      2.023      0.21     -80    38
# Comp:  2          [OIII]5007_d      26.22      0.26     -80    38
# Comp:  2            [OI]6300_d      1.802      0.26     -80    38
# Comp:  2           [NII]6583_d      12.90      0.26     -80    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -154       129
#  comp.  1:       -82        32
#  comp.  2:       -82        33
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.36      0.20     -82    32
# Comp:  1                Halpha      45.44      0.20     -82    32
# Comp:  2             [SII]6716      10.10      0.20     -82    33
# Comp:  2             [SII]6731      7.547      0.20     -82    33
# Comp:  2              HeII4687     0.4181      0.20     -82    33
# Comp:  2               HeI5876      1.959      0.20     -82    33
# Comp:  2          [OIII]5007_d      22.40      0.26     -82    33
# Comp:  2            [OI]6300_d      1.630      0.26     -82    33
# Comp:  2           [NII]6583_d      13.11      0.26     -82    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61       140
#  comp.  1:       -81        32
#  comp.  2:       -78        24
# chi2/DOF: 1.201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.81      0.20     -81    32
# Comp:  1                Halpha      45.97      0.20     -81    32
# Comp:  2             [SII]6716      9.715      0.20     -78    24
# Comp:  2             [SII]6731      6.879      0.20     -78    24
# Comp:  2              HeII4687     0.6710      0.20     -78    24
# Comp:  2               HeI5876      1.816      0.20     -78    24
# Comp:  2          [OIII]5007_d      22.90      0.25     -78    24
# Comp:  2            [OI]6300_d      1.843      0.25     -78    24
# Comp:  2           [NII]6583_d      11.13      0.25     -78    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       209
#  comp.  1:       -83        31
#  comp.  2:       -81        37
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.858      0.20     -83    31
# Comp:  1                Halpha      45.34      0.20     -83    31
# Comp:  2             [SII]6716      10.54      0.21     -81    37
# Comp:  2             [SII]6731      7.557      0.21     -81    37
# Comp:  2              HeII4687     0.4313      0.21     -81    37
# Comp:  2               HeI5876      1.900      0.21     -81    37
# Comp:  2          [OIII]5007_d      22.55      0.26     -81    37
# Comp:  2            [OI]6300_d      1.784      0.26     -81    37
# Comp:  2           [NII]6583_d      12.51      0.26     -81    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80       181
#  comp.  1:       -82        29
#  comp.  2:       -84        32
# chi2/DOF: 1.208; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.26      0.20     -82    29
# Comp:  1                Halpha      45.10      0.20     -82    29
# Comp:  2             [SII]6716      10.16      0.20     -84    32
# Comp:  2             [SII]6731      7.944      0.20     -84    32
# Comp:  2              HeII4687     0.5178      0.20     -84    32
# Comp:  2               HeI5876      1.994      0.20     -84    32
# Comp:  2          [OIII]5007_d      25.42      0.26     -84    32
# Comp:  2            [OI]6300_d      1.517      0.26     -84    32
# Comp:  2           [NII]6583_d      12.45      0.26     -84    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83       153
#  comp.  1:       -81        30
#  comp.  2:       -79        38
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.36      0.20     -81    30
# Comp:  1                Halpha      44.68      0.20     -81    30
# Comp:  2             [SII]6716      10.39      0.21     -79    38
# Comp:  2             [SII]6731      7.880      0.21     -79    38
# Comp:  2              HeII4687     0.5634      0.21     -79    38
# Comp:  2               HeI5876      1.954      0.21     -79    38
# Comp:  2          [OIII]5007_d      26.11      0.26     -79    38
# Comp:  2            [OI]6300_d      1.809      0.26     -79    38
# Comp:  2           [NII]6583_d      12.48      0.26     -79    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -173       220
#  comp.  1:       -80        30
#  comp.  2:       -80        30
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.11      0.20     -80    30
# Comp:  1                Halpha      45.04      0.20     -80    30
# Comp:  2             [SII]6716      9.766      0.20     -80    30
# Comp:  2             [SII]6731      6.300      0.20     -80    30
# Comp:  2              HeII4687     0.5402      0.20     -80    30
# Comp:  2               HeI5876      1.998      0.20     -80    30
# Comp:  2          [OIII]5007_d      23.19      0.26     -80    30
# Comp:  2            [OI]6300_d      1.742      0.26     -80    30
# Comp:  2           [NII]6583_d      11.53      0.26     -80    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -162       101
#  comp.  1:       -81        29
#  comp.  2:       -79        41
# chi2/DOF: 1.229; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.09      0.20     -81    29
# Comp:  1                Halpha      44.63      0.20     -81    29
# Comp:  2             [SII]6716      10.58      0.21     -79    41
# Comp:  2             [SII]6731      6.978      0.21     -79    41
# Comp:  2              HeII4687     0.5127      0.21     -79    41
# Comp:  2               HeI5876      1.924      0.21     -79    41
# Comp:  2          [OIII]5007_d      24.78      0.26     -79    41
# Comp:  2            [OI]6300_d      1.759      0.26     -79    41
# Comp:  2           [NII]6583_d      12.56      0.26     -79    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        94
#  comp.  1:       -80        30
#  comp.  2:       -80        25
# chi2/DOF: 1.212; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.64      0.20     -80    30
# Comp:  1                Halpha      45.25      0.20     -80    30
# Comp:  2             [SII]6716      10.12      0.20     -80    25
# Comp:  2             [SII]6731      7.386      0.20     -80    25
# Comp:  2              HeII4687     0.6825      0.20     -80    25
# Comp:  2               HeI5876      1.910      0.20     -80    25
# Comp:  2          [OIII]5007_d      23.01      0.25     -80    25
# Comp:  2            [OI]6300_d      1.804      0.25     -80    25
# Comp:  2           [NII]6583_d      11.64      0.25     -80    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -150       156
#  comp.  1:       -82        34
#  comp.  2:       -80        38
# chi2/DOF: 1.205; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.19      0.21     -82    34
# Comp:  1                Halpha      45.80      0.21     -82    34
# Comp:  2             [SII]6716      10.25      0.21     -80    38
# Comp:  2             [SII]6731      6.352      0.21     -80    38
# Comp:  2              HeII4687     0.2917      0.21     -80    38
# Comp:  2               HeI5876      2.019      0.21     -80    38
# Comp:  2          [OIII]5007_d      24.32      0.26     -80    38
# Comp:  2            [OI]6300_d      1.487      0.26     -80    38
# Comp:  2           [NII]6583_d      12.40      0.26     -80    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143       256
#  comp.  1:       -82        33
#  comp.  2:       -76        30
# chi2/DOF: 1.203; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.12      0.20     -82    33
# Comp:  1                Halpha      45.61      0.20     -82    33
# Comp:  2             [SII]6716      9.966      0.20     -76    30
# Comp:  2             [SII]6731      7.340      0.20     -76    30
# Comp:  2              HeII4687     0.3523      0.20     -76    30
# Comp:  2               HeI5876      1.958      0.20     -76    30
# Comp:  2          [OIII]5007_d      23.20      0.26     -76    30
# Comp:  2            [OI]6300_d      1.917      0.26     -76    30
# Comp:  2           [NII]6583_d      11.81      0.26     -76    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110       113
#  comp.  1:       -82        34
#  comp.  2:       -83        41
# chi2/DOF: 1.201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.46      0.21     -82    34
# Comp:  1                Halpha      45.99      0.21     -82    34
# Comp:  2             [SII]6716      10.49      0.21     -83    41
# Comp:  2             [SII]6731      8.704      0.21     -83    41
# Comp:  2              HeII4687     0.3961      0.21     -83    41
# Comp:  2               HeI5876      2.042      0.21     -83    41
# Comp:  2          [OIII]5007_d      25.37      0.27     -83    41
# Comp:  2            [OI]6300_d      1.791      0.27     -83    41
# Comp:  2           [NII]6583_d      13.09      0.27     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       167
#  comp.  1:       -81        26
#  comp.  2:       -81        38
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.31      0.20     -81    26
# Comp:  1                Halpha      44.25      0.20     -81    26
# Comp:  2             [SII]6716      10.33      0.21     -81    38
# Comp:  2             [SII]6731      8.158      0.21     -81    38
# Comp:  2              HeII4687     0.6964      0.21     -81    38
# Comp:  2               HeI5876      1.952      0.21     -81    38
# Comp:  2          [OIII]5007_d      24.21      0.26     -81    38
# Comp:  2            [OI]6300_d      1.948      0.26     -81    38
# Comp:  2           [NII]6583_d      12.57      0.26     -81    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -155       166
#  comp.  1:       -81        31
#  comp.  2:       -86        28
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.36      0.20     -81    31
# Comp:  1                Halpha      44.90      0.20     -81    31
# Comp:  2             [SII]6716      9.701      0.20     -86    28
# Comp:  2             [SII]6731      7.400      0.20     -86    28
# Comp:  2              HeII4687     0.5659      0.20     -86    28
# Comp:  2               HeI5876      1.940      0.20     -86    28
# Comp:  2          [OIII]5007_d      24.02      0.25     -86    28
# Comp:  2            [OI]6300_d      1.540      0.25     -86    28
# Comp:  2           [NII]6583_d      12.55      0.25     -86    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -172        96
#  comp.  1:       -83        30
#  comp.  2:       -82        43
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.73      0.20     -83    30
# Comp:  1                Halpha      45.42      0.20     -83    30
# Comp:  2             [SII]6716      10.13      0.21     -82    43
# Comp:  2             [SII]6731      7.772      0.21     -82    43
# Comp:  2              HeII4687     0.4251      0.21     -82    43
# Comp:  2               HeI5876      1.970      0.21     -82    43
# Comp:  2          [OIII]5007_d      23.49      0.27     -82    43
# Comp:  2            [OI]6300_d      1.492      0.27     -82    43
# Comp:  2           [NII]6583_d      12.17      0.27     -82    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       153
#  comp.  1:       -83        29
#  comp.  2:       -84        31
# chi2/DOF: 1.238; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.34      0.20     -83    29
# Comp:  1                Halpha      45.20      0.20     -83    29
# Comp:  2             [SII]6716      10.24      0.20     -84    31
# Comp:  2             [SII]6731      7.885      0.20     -84    31
# Comp:  2              HeII4687     0.6849      0.20     -84    31
# Comp:  2               HeI5876      1.883      0.20     -84    31
# Comp:  2          [OIII]5007_d      25.38      0.26     -84    31
# Comp:  2            [OI]6300_d      1.825      0.26     -84    31
# Comp:  2           [NII]6583_d      12.30      0.26     -84    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139       158
#  comp.  1:       -82        30
#  comp.  2:       -83        43
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.40      0.20     -82    30
# Comp:  1                Halpha      44.56      0.20     -82    30
# Comp:  2             [SII]6716      10.38      0.21     -83    43
# Comp:  2             [SII]6731      7.473      0.21     -83    43
# Comp:  2              HeII4687     0.6448      0.21     -83    43
# Comp:  2               HeI5876      2.152      0.21     -83    43
# Comp:  2          [OIII]5007_d      25.55      0.27     -83    43
# Comp:  2            [OI]6300_d      1.757      0.27     -83    43
# Comp:  2           [NII]6583_d      12.20      0.27     -83    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        40
#  comp.  1:       -81        30
#  comp.  2:       -83        33
# chi2/DOF: 1.235; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.33      0.20     -81    30
# Comp:  1                Halpha      45.20      0.20     -81    30
# Comp:  2             [SII]6716      10.23      0.20     -83    33
# Comp:  2             [SII]6731      7.929      0.20     -83    33
# Comp:  2              HeII4687     0.5989      0.20     -83    33
# Comp:  2               HeI5876      1.970      0.20     -83    33
# Comp:  2          [OIII]5007_d      25.94      0.26     -83    33
# Comp:  2            [OI]6300_d      1.659      0.26     -83    33
# Comp:  2           [NII]6583_d      12.08      0.26     -83    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       153
#  comp.  1:       -83        32
#  comp.  2:       -83        37
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.73      0.20     -83    32
# Comp:  1                Halpha      45.84      0.20     -83    32
# Comp:  2             [SII]6716      10.25      0.21     -83    37
# Comp:  2             [SII]6731      6.476      0.21     -83    37
# Comp:  2              HeII4687     0.3666      0.21     -83    37
# Comp:  2               HeI5876      2.080      0.21     -83    37
# Comp:  2          [OIII]5007_d      26.44      0.26     -83    37
# Comp:  2            [OI]6300_d      1.695      0.26     -83    37
# Comp:  2           [NII]6583_d      12.48      0.26     -83    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -172       147
#  comp.  1:       -83        28
#  comp.  2:       -81        38
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.27      0.20     -83    28
# Comp:  1                Halpha      45.07      0.20     -83    28
# Comp:  2             [SII]6716      10.44      0.21     -81    38
# Comp:  2             [SII]6731      8.069      0.21     -81    38
# Comp:  2              HeII4687     0.3084      0.21     -81    38
# Comp:  2               HeI5876      2.126      0.21     -81    38
# Comp:  2          [OIII]5007_d      23.84      0.26     -81    38
# Comp:  2            [OI]6300_d      1.765      0.26     -81    38
# Comp:  2           [NII]6583_d      12.40      0.26     -81    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -131       117
#  comp.  1:       -83        30
#  comp.  2:       -81        42
# chi2/DOF: 1.213; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.21      0.20     -83    30
# Comp:  1                Halpha      45.36      0.20     -83    30
# Comp:  2             [SII]6716      10.69      0.21     -81    42
# Comp:  2             [SII]6731      8.057      0.21     -81    42
# Comp:  2              HeII4687     0.5796      0.21     -81    42
# Comp:  2               HeI5876      2.028      0.21     -81    42
# Comp:  2          [OIII]5007_d      25.20      0.27     -81    42
# Comp:  2            [OI]6300_d      1.922      0.27     -81    42
# Comp:  2           [NII]6583_d      11.70      0.27     -81    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       123
#  comp.  1:       -80        29
#  comp.  2:       -84        25
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.73      0.20     -80    29
# Comp:  1                Halpha      44.95      0.20     -80    29
# Comp:  2             [SII]6716      9.758      0.20     -84    25
# Comp:  2             [SII]6731      7.826      0.20     -84    25
# Comp:  2              HeII4687     0.4957      0.20     -84    25
# Comp:  2               HeI5876      1.858      0.20     -84    25
# Comp:  2          [OIII]5007_d      24.68      0.25     -84    25
# Comp:  2            [OI]6300_d      1.489      0.25     -84    25
# Comp:  2           [NII]6583_d      12.01      0.25     -84    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134       163
#  comp.  1:       -80        30
#  comp.  2:       -78        40
# chi2/DOF: 1.262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.14      0.20     -80    30
# Comp:  1                Halpha      44.54      0.20     -80    30
# Comp:  2             [SII]6716      10.20      0.21     -78    40
# Comp:  2             [SII]6731      8.223      0.21     -78    40
# Comp:  2              HeII4687     0.3139      0.21     -78    40
# Comp:  2               HeI5876      1.861      0.21     -78    40
# Comp:  2          [OIII]5007_d      24.52      0.26     -78    40
# Comp:  2            [OI]6300_d      1.485      0.26     -78    40
# Comp:  2           [NII]6583_d      12.44      0.26     -78    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121       151
#  comp.  1:       -81        30
#  comp.  2:       -81        37
# chi2/DOF: 1.212; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.66      0.20     -81    30
# Comp:  1                Halpha      44.66      0.20     -81    30
# Comp:  2             [SII]6716      10.63      0.21     -81    37
# Comp:  2             [SII]6731      8.133      0.21     -81    37
# Comp:  2              HeII4687     0.4148      0.21     -81    37
# Comp:  2               HeI5876      2.040      0.21     -81    37
# Comp:  2          [OIII]5007_d      26.01      0.26     -81    37
# Comp:  2            [OI]6300_d      1.668      0.26     -81    37
# Comp:  2           [NII]6583_d      12.35      0.26     -81    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145       109
#  comp.  1:       -81        26
#  comp.  2:       -80        37
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.22      0.20     -81    26
# Comp:  1                Halpha      44.28      0.20     -81    26
# Comp:  2             [SII]6716      10.66      0.21     -80    37
# Comp:  2             [SII]6731      6.372      0.21     -80    37
# Comp:  2              HeII4687     0.5280      0.21     -80    37
# Comp:  2               HeI5876      2.023      0.21     -80    37
# Comp:  2          [OIII]5007_d      26.19      0.26     -80    37
# Comp:  2            [OI]6300_d      1.735      0.26     -80    37
# Comp:  2           [NII]6583_d      12.97      0.26     -80    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -130       117
#  comp.  1:       -80        32
#  comp.  2:       -78        40
# chi2/DOF: 1.237; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.41      0.20     -80    32
# Comp:  1                Halpha      45.32      0.20     -80    32
# Comp:  2             [SII]6716      10.25      0.21     -78    40
# Comp:  2             [SII]6731      7.491      0.21     -78    40
# Comp:  2              HeII4687     0.3932      0.21     -78    40
# Comp:  2               HeI5876      1.899      0.21     -78    40
# Comp:  2          [OIII]5007_d      23.13      0.26     -78    40
# Comp:  2            [OI]6300_d      1.499      0.26     -78    40
# Comp:  2           [NII]6583_d      13.27      0.26     -78    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68       198
#  comp.  1:       -82        32
#  comp.  2:       -79        33
# chi2/DOF: 1.231; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.40      0.20     -82    32
# Comp:  1                Halpha      45.58      0.20     -82    32
# Comp:  2             [SII]6716      9.948      0.20     -79    33
# Comp:  2             [SII]6731      6.850      0.20     -79    33
# Comp:  2              HeII4687     0.8144      0.20     -79    33
# Comp:  2               HeI5876      1.865      0.20     -79    33
# Comp:  2          [OIII]5007_d      22.14      0.26     -79    33
# Comp:  2            [OI]6300_d      1.815      0.26     -79    33
# Comp:  2           [NII]6583_d      12.39      0.26     -79    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158       157
#  comp.  1:       -80        31
#  comp.  2:       -82        29
# chi2/DOF: 1.234; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.68      0.20     -80    31
# Comp:  1                Halpha      45.04      0.20     -80    31
# Comp:  2             [SII]6716      9.834      0.20     -82    29
# Comp:  2             [SII]6731      8.321      0.20     -82    29
# Comp:  2              HeII4687     0.4498      0.20     -82    29
# Comp:  2               HeI5876      2.020      0.20     -82    29
# Comp:  2          [OIII]5007_d      24.99      0.25     -82    29
# Comp:  2            [OI]6300_d      1.937      0.25     -82    29
# Comp:  2           [NII]6583_d      11.67      0.25     -82    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110       119
#  comp.  1:       -81        31
#  comp.  2:       -77        37
# chi2/DOF: 1.213; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.68      0.20     -81    31
# Comp:  1                Halpha      45.72      0.20     -81    31
# Comp:  2             [SII]6716      10.01      0.21     -77    37
# Comp:  2             [SII]6731      6.729      0.21     -77    37
# Comp:  2              HeII4687     0.4285      0.21     -77    37
# Comp:  2               HeI5876      2.075      0.21     -77    37
# Comp:  2          [OIII]5007_d      24.06      0.26     -77    37
# Comp:  2            [OI]6300_d      1.787      0.26     -77    37
# Comp:  2           [NII]6583_d      11.84      0.26     -77    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140       228
#  comp.  1:       -80        32
#  comp.  2:       -83        44
# chi2/DOF: 1.212; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.20      0.20     -80    32
# Comp:  1                Halpha      45.01      0.20     -80    32
# Comp:  2             [SII]6716      10.50      0.21     -83    44
# Comp:  2             [SII]6731      7.512      0.21     -83    44
# Comp:  2              HeII4687     0.6470      0.21     -83    44
# Comp:  2               HeI5876      1.995      0.21     -83    44
# Comp:  2          [OIII]5007_d      25.79      0.27     -83    44
# Comp:  2            [OI]6300_d      1.849      0.27     -83    44
# Comp:  2           [NII]6583_d      13.37      0.27     -83    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139       111
#  comp.  1:       -80        31
#  comp.  2:       -76        41
# chi2/DOF: 1.232; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.93      0.20     -80    31
# Comp:  1                Halpha      45.04      0.20     -80    31
# Comp:  2             [SII]6716      10.09      0.21     -76    41
# Comp:  2             [SII]6731      7.091      0.21     -76    41
# Comp:  2              HeII4687     0.4374      0.21     -76    41
# Comp:  2               HeI5876      2.019      0.21     -76    41
# Comp:  2          [OIII]5007_d      23.12      0.27     -76    41
# Comp:  2            [OI]6300_d      1.654      0.27     -76    41
# Comp:  2           [NII]6583_d      12.79      0.27     -76    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133       131
#  comp.  1:       -81        31
#  comp.  2:       -82        43
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.58      0.20     -81    31
# Comp:  1                Halpha      45.00      0.20     -81    31
# Comp:  2             [SII]6716      10.39      0.21     -82    43
# Comp:  2             [SII]6731      7.116      0.21     -82    43
# Comp:  2              HeII4687     0.3844      0.21     -82    43
# Comp:  2               HeI5876      1.876      0.21     -82    43
# Comp:  2          [OIII]5007_d      25.46      0.27     -82    43
# Comp:  2            [OI]6300_d      1.634      0.27     -82    43
# Comp:  2           [NII]6583_d      13.49      0.27     -82    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121       157
#  comp.  1:       -83        31
#  comp.  2:       -76        43
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.965      0.20     -83    31
# Comp:  1                Halpha      45.29      0.20     -83    31
# Comp:  2             [SII]6716      10.55      0.21     -76    43
# Comp:  2             [SII]6731      7.527      0.21     -76    43
# Comp:  2              HeII4687     0.4210      0.21     -76    43
# Comp:  2               HeI5876      1.880      0.21     -76    43
# Comp:  2          [OIII]5007_d      23.45      0.27     -76    43
# Comp:  2            [OI]6300_d      1.720      0.27     -76    43
# Comp:  2           [NII]6583_d      12.57      0.27     -76    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       114
#  comp.  1:       -83        30
#  comp.  2:       -80        42
# chi2/DOF: 1.202; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.00      0.20     -83    30
# Comp:  1                Halpha      45.69      0.20     -83    30
# Comp:  2             [SII]6716      10.49      0.21     -80    42
# Comp:  2             [SII]6731      7.671      0.21     -80    42
# Comp:  2              HeII4687     0.5032      0.21     -80    42
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.23      0.20     -80    32
# Comp:  1                Halpha      44.92      0.20     -80    32
# Comp:  2             [SII]6716      9.487      0.20     -82    25
# Comp:  2             [SII]6731      7.510      0.20     -82    25
# Comp:  2              HeII4687     0.5344      0.20     -82    25
# Comp:  2               HeI5876      1.933      0.20     -82    25
# Comp:  2          [OIII]5007_d      24.70      0.25     -82    25
# Comp:  2            [OI]6300_d      1.649      0.25     -82    25
# Comp:  2           [NII]6583_d      12.09      0.25     -82    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95       183
#  comp.  1:       -82        31
#  comp.  2:       -74        38
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.30      0.20     -82    31
# Comp:  1                Halpha      45.28      0.20     -82    31
# Comp:  2             [SII]6716      10.27      0.21     -74    38
# Comp:  2             [SII]6731      7.498      0.21     -74    38
# Comp:  2              HeII4687     0.8495      0.21     -74    38
# Comp:  2               HeI5876      2.002      0.21     -74    38
# Comp:  2          [OIII]5007_d      24.22      0.26     -74    38
# Comp:  2            [OI]6300_d      1.712      0.26     -74    38
# Comp:  2           [NII]6583_d      12.85      0.26     -74    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112       110
#  comp.  1:       -81        34
#  comp.  2:       -80        40
# chi2/DOF: 1.262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.59      0.21     -81    34
# Comp:  1                Halpha      46.00      0.21     -81    34
# Comp:  2             [SII]6716      10.31      0.21     -80    40
# Comp:  2             [SII]6731      7.712      0.21     -80    40
# Comp:  2              HeII4687     0.5271      0.21     -80    40
# Comp:  2               HeI5876      1.924      0.21     -80    40
# Comp:  2          [OIII]5007_d      24.66      0.26     -80    40
# Comp:  2            [OI]6300_d      1.587      0.26     -80    40
# Comp:  2           [NII]6583_d      11.58      0.26     -80    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88       145
#  comp.  1:       -81        33
#  comp.  2:       -83        33
# chi2/DOF: 1.262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.62      0.20     -81    33
# Comp:  1                Halpha      45.92      0.20     -81    33
# Comp:  2             [SII]6716      9.997      0.20     -83    33
# Comp:  2             [SII]6731      7.979      0.20     -83    33
# Comp:  2              HeII4687     0.4180      0.20     -83    33
# Comp:  2               HeI5876      1.917      0.20     -83    33
# Comp:  2          [OIII]5007_d      24.05      0.26     -83    33
# Comp:  2            [OI]6300_d      1.810      0.26     -83    33
# Comp:  2           [NII]6583_d      12.12      0.26     -83    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       228
#  comp.  1:       -83        28
#  comp.  2:       -78        34
# chi2/DOF: 1.205; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.23      0.20     -83    28
# Comp:  1                Halpha      45.18      0.20     -83    28
# Comp:  2             [SII]6716      9.894      0.20     -78    34
# Comp:  2             [SII]6731      8.428      0.20     -78    34
# Comp:  2              HeII4687     0.4157      0.20     -78    34
# Comp:  2               HeI5876      1.966      0.20     -78    34
# Comp:  2          [OIII]5007_d      23.53      0.26     -78    34
# Comp:  2            [OI]6300_d      1.571      0.26     -78    34
# Comp:  2           [NII]6583_d      11.79      0.26     -78    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       188
#  comp.  1:       -81        27
#  comp.  2:       -81        33
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.44      0.20     -81    27
# Comp:  1                Halpha      44.64      0.20     -81    27
# Comp:  2             [SII]6716      9.684      0.20     -81    33
# Comp:  2             [SII]6731      7.895      0.20     -81    33
# Comp:  2              HeII4687     0.3895      0.20     -81    33
# Comp:  2               HeI5876      1.921      0.20     -81    33
# Comp:  2          [OIII]5007_d      22.26      0.26     -81    33
# Comp:  2            [OI]6300_d      1.512      0.26     -81    33
# Comp:  2           [NII]6583_d      12.43      0.26     -81    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       182
#  comp.  1:       -81        31
#  comp.  2:       -80        39
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.23      0.20     -81    31
# Comp:  1                Halpha      44.91      0.20     -81    31
# Comp:  2             [SII]6716      10.42      0.21     -80    39
# Comp:  2             [SII]6731      7.718      0.21     -80    39
# Comp:  2              HeII4687     0.6664      0.21     -80    39
# Comp:  2               HeI5876      2.070      0.21     -80    39
# Comp:  2          [OIII]5007_d      22.85      0.26     -80    39
# Comp:  2            [OI]6300_d      1.616      0.26     -80    39
# Comp:  2           [NII]6583_d      12.15      0.26     -80    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70       156
#  comp.  1:       -83        29
#  comp.  2:       -84        35
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.54      0.20     -83    29
# Comp:  1                Halpha      45.31      0.20     -83    29
# Comp:  2             [SII]6716      9.788      0.21     -84    35
# Comp:  2             [SII]6731      7.337      0.21     -84    35
# Comp:  2              HeII4687     0.5939      0.21     -84    35
# Comp:  2               HeI5876      1.846      0.21     -84    35
# Comp:  2          [OIII]5007_d      24.80      0.26     -84    35
# Comp:  2            [OI]6300_d      1.798      0.26     -84    35
# Comp:  2           [NII]6583_d      12.31      0.26     -84    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        70
#  comp.  1:       -83        30
#  comp.  2:       -77        46
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.41      0.20     -83    30
# Comp:  1                Halpha      45.20      0.20     -83    30
# Comp:  2             [SII]6716      10.63      0.21     -77    46
# Comp:  2             [SII]6731      8.345      0.21     -77    46
# Comp:  2              HeII4687     0.3894      0.21     -77    46
# Comp:  2               HeI5876      2.188      0.21     -77    46
# Comp:  2          [OIII]5007_d      23.81      0.27     -77    46
# Comp:  2            [OI]6300_d      1.709      0.27     -77    46
# Comp:  2           [NII]6583_d      12.80      0.27     -77    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -148       193
#  comp.  1:       -81        33
#  comp.  2:       -80        30
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.15      0.20     -81    33
# Comp:  1                Halpha      45.73      0.20     -81    33
# Comp:  2             [SII]6716      10.12      0.20     -80    30
# Comp:  2             [SII]6731      7.508      0.20     -80    30
# Comp:  2              HeII4687     0.6526      0.20     -80    30
# Comp:  2               HeI5876      2.036      0.20     -80    30
# Comp:  2          [OIII]5007_d      22.10      0.26     -80    30
# Comp:  2            [OI]6300_d      1.660      0.26     -80    30
# Comp:  2           [NII]6583_d      11.45      0.26     -80    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -173       207
#  comp.  1:       -80        33
#  comp.  2:       -84        27
# chi2/DOF: 1.229; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.35      0.20     -80    33
# Comp:  1                Halpha      45.15      0.20     -80    33
# Comp:  2             [SII]6716      9.936      0.20     -84    27
# Comp:  2             [SII]6731      7.448      0.20     -84    27
# Comp:  2              HeII4687     0.5107      0.20     -84    27
# Comp:  2               HeI5876      2.029      0.20     -84    27
# Comp:  2          [OIII]5007_d      25.18      0.25     -84    27
# Comp:  2            [OI]6300_d      1.606      0.25     -84    27
# Comp:  2           [NII]6583_d      11.62      0.25     -84    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135       137
#  comp.  1:       -81        27
#  comp.  2:       -79        34
# chi2/DOF: 1.207; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.73      0.20     -81    27
# Comp:  1                Halpha      44.54      0.20     -81    27
# Comp:  2             [SII]6716      10.25      0.21     -79    34
# Comp:  2             [SII]6731      7.183      0.21     -79    34
# Comp:  2              HeII4687     0.3770      0.21     -79    34
# Comp:  2               HeI5876      2.081      0.21     -79    34
# Comp:  2          [OIII]5007_d      23.52      0.26     -79    34
# Comp:  2            [OI]6300_d      1.830      0.26     -79    34
# Comp:  2           [NII]6583_d      12.86      0.26     -79    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123       144
#  comp.  1:       -81        31
#  comp.  2:       -80        36
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.53      0.20     -81    31
# Comp:  1                Halpha      45.15      0.20     -81    31
# Comp:  2             [SII]6716      10.46      0.21     -80    36
# Comp:  2             [SII]6731      7.237      0.21     -80    36
# Comp:  2              HeII4687     0.7317      0.21     -80    36
# Comp:  2               HeI5876      1.971      0.21     -80    36
# Comp:  2          [OIII]5007_d      22.63      0.26     -80    36
# Comp:  2            [OI]6300_d      1.951      0.26     -80    36
# Comp:  2           [NII]6583_d      12.54      0.26     -80    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       128
#  comp.  1:       -82        33
#  comp.  2:       -84        36
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.71      0.20     -82    33
# Comp:  1                Halpha      45.76      0.20     -82    33
# Comp:  2             [SII]6716      10.14      0.21     -84    36
# Comp:  2             [SII]6731      7.691      0.21     -84    36
# Comp:  2              HeII4687     0.4741      0.21     -84    36
# Comp:  2               HeI5876      2.022      0.21     -84    36
# Comp:  2          [OIII]5007_d      24.45      0.26     -84    36
# Comp:  2            [OI]6300_d      1.841      0.26     -84    36
# Comp:  2           [NII]6583_d      12.11      0.26     -84    36
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.53974682, 0.65014273, 0.42563661, 0.84253454, 0.13436777,
#        0.11896531, 1.2486597 , 0.21254951, 0.70093302])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([12.43887891, 61.69920374, 14.30992311, 10.48742929,  0.52474692,
#         2.40385146, 25.35351102,  2.26747358, 16.91083548])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_3_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_3", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_3_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_3_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_3_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.634637    0.078559
# 1        Halpha  3.147922    0.033171
# 2     [SII]6716  0.730099    0.021716
# 3     [SII]6731  0.535073    0.042986
# 4      HeII4687  0.026773    0.006856
# 5       HeI5876  0.122646    0.006070
# 6  [OIII]5007_d  1.293548    0.063707
# 7    [OI]6300_d  0.115688    0.010844
# 8   [NII]6583_d  0.862799    0.035762
#           Name      Flux  Error_flux
# 0        Hbeta  0.634637    0.078559
# 1       Halpha  3.147922    0.033171
# 2    [SII]6716  0.730099    0.021716
# 3    [SII]6731  0.535073    0.042986
# 4     HeII4687  0.026773    0.006856
# 5      HeI5876  0.122646    0.006070
# 6   [OIII]4959  0.323387    0.063707
# 7   [OIII]5007  0.970161    0.063707
# 8     [OI]6300  0.086766    0.010844
# 9     [OI]6364  0.028922    0.010844
# 10   [NII]6548  0.215700    0.035762
# 11   [NII]6583  0.647099    0.035762

# %%
np.median(flux_rf_rebin)
# Out:
# 0.05102045683503015
