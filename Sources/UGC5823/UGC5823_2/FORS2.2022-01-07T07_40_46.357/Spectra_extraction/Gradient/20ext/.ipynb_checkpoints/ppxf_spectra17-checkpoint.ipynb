# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_17.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188  
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_17']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.10508228 0.11774666 0.09609745 ... 0.04572509 0.04286829 0.04219826] [0.0061128 0.0061128 0.0061128 ... 0.0061128 0.0061128 0.0061128]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        38
# chi2/DOF: 0.007175; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        33
# chi2/DOF: 0.004717; DOF: 1904; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-11.89622381,  33.09397492])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -62       159
#  comp.  1:       -53        31
#  comp.  2:       -50        35
# chi2/DOF: 2.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.15      0.19     -53    31
# Comp:  1                Halpha      93.10      0.19     -53    31
# Comp:  2             [SII]6716      16.40      0.19     -50    35
# Comp:  2             [SII]6731      11.64      0.19     -50    35
# Comp:  2              HeII4687      0.000      0.19     -50    35
# Comp:  2               HeI5876      3.730      0.19     -50    35
# Comp:  2          [OIII]5007_d      60.17      0.24     -50    35
# Comp:  2            [OI]6300_d      2.042      0.24     -50    35
# Comp:  2           [NII]6583_d      21.31      0.24     -50    35
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  151.8; gas flux:     34 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  411.1; gas flux:    127 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  70.35; gas flux:     23 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  52.42; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  16.21; gas flux:      5 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  201.8; gas flux:     63 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  6.962; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  70.69; gas flux:     29 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        66         1
#  comp.  1:       -53        37
#  comp.  2:       -54        26
# chi2/DOF: 1.790; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.00      0.19     -53    37
# Comp:  1                Halpha      96.24      0.19     -53    37
# Comp:  2             [SII]6716      16.14      0.18     -54    26
# Comp:  2             [SII]6731      12.39      0.18     -54    26
# Comp:  2              HeII4687      0.000      0.18     -54    26
# Comp:  2               HeI5876      3.622      0.18     -54    26
# Comp:  2          [OIII]5007_d      58.59      0.23     -54    26
# Comp:  2            [OI]6300_d      1.412      0.23     -54    26
# Comp:  2           [NII]6583_d      20.88      0.23     -54    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        96
#  comp.  1:       -51        33
#  comp.  2:       -49        29
# chi2/DOF: 1.980; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.72      0.19     -51    33
# Comp:  1                Halpha      94.08      0.19     -51    33
# Comp:  2             [SII]6716      16.28      0.19     -49    29
# Comp:  2             [SII]6731      11.31      0.19     -49    29
# Comp:  2              HeII4687      0.000      0.19     -49    29
# Comp:  2               HeI5876      3.859      0.19     -49    29
# Comp:  2          [OIII]5007_d      57.65      0.23     -49    29
# Comp:  2            [OI]6300_d      2.005      0.23     -49    29
# Comp:  2           [NII]6583_d      21.55      0.23     -49    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14       130
#  comp.  1:       -55        27
#  comp.  2:       -46        39
# chi2/DOF: 1.800; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.18      0.18     -55    27
# Comp:  1                Halpha      92.78      0.18     -55    27
# Comp:  2             [SII]6716      15.21      0.19     -46    39
# Comp:  2             [SII]6731      13.22      0.19     -46    39
# Comp:  2              HeII4687      0.000      0.19     -46    39
# Comp:  2               HeI5876      3.579      0.19     -46    39
# Comp:  2          [OIII]5007_d      58.25      0.24     -46    39
# Comp:  2            [OI]6300_d      1.890      0.24     -46    39
# Comp:  2           [NII]6583_d      21.46      0.24     -46    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       208
#  comp.  1:       -53        26
#  comp.  2:       -56        28
# chi2/DOF: 1.880; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.61      0.18     -53    26
# Comp:  1                Halpha      91.28      0.18     -53    26
# Comp:  2             [SII]6716      16.22      0.18     -56    28
# Comp:  2             [SII]6731      11.43      0.18     -56    28
# Comp:  2              HeII4687    0.02891      0.18     -56    28
# Comp:  2               HeI5876      3.659      0.18     -56    28
# Comp:  2          [OIII]5007_d      57.26      0.23     -56    28
# Comp:  2            [OI]6300_d      1.644      0.23     -56    28
# Comp:  2           [NII]6583_d      20.63      0.23     -56    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        81         1
#  comp.  1:       -55        25
#  comp.  2:       -55        28
# chi2/DOF: 1.669; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.82      0.18     -55    25
# Comp:  1                Halpha      91.40      0.18     -55    25
# Comp:  2             [SII]6716      16.80      0.19     -55    28
# Comp:  2             [SII]6731      10.24      0.19     -55    28
# Comp:  2              HeII4687      0.000      0.19     -55    28
# Comp:  2               HeI5876      3.465      0.19     -55    28
# Comp:  2          [OIII]5007_d      61.42      0.23     -55    28
# Comp:  2            [OI]6300_d      2.146      0.23     -55    28
# Comp:  2           [NII]6583_d      20.01      0.23     -55    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59         1
#  comp.  1:       -54        22
#  comp.  2:       -44        38
# chi2/DOF: 1.725; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.99      0.18     -54    22
# Comp:  1                Halpha      91.20      0.18     -54    22
# Comp:  2             [SII]6716      16.36      0.19     -44    38
# Comp:  2             [SII]6731      11.93      0.19     -44    38
# Comp:  2              HeII4687      0.000      0.19     -44    38
# Comp:  2               HeI5876      4.016      0.19     -44    38
# Comp:  2          [OIII]5007_d      58.35      0.24     -44    38
# Comp:  2            [OI]6300_d      1.816      0.24     -44    38
# Comp:  2           [NII]6583_d      21.04      0.24     -44    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90       156
#  comp.  1:       -52        34
#  comp.  2:       -57        33
# chi2/DOF: 1.889; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.34      0.19     -52    34
# Comp:  1                Halpha      94.05      0.19     -52    34
# Comp:  2             [SII]6716      15.42      0.19     -57    33
# Comp:  2             [SII]6731      12.61      0.19     -57    33
# Comp:  2              HeII4687    0.04539      0.19     -57    33
# Comp:  2               HeI5876      3.681      0.19     -57    33
# Comp:  2          [OIII]5007_d      60.61      0.24     -57    33
# Comp:  2            [OI]6300_d      2.167      0.24     -57    33
# Comp:  2           [NII]6583_d      21.33      0.24     -57    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       107         1
#  comp.  1:       -54        26
#  comp.  2:       -45        47
# chi2/DOF: 1.712; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.86      0.18     -54    26
# Comp:  1                Halpha      91.44      0.18     -54    26
# Comp:  2             [SII]6716      17.66      0.20     -45    47
# Comp:  2             [SII]6731      12.19      0.20     -45    47
# Comp:  2              HeII4687    0.01251      0.20     -45    47
# Comp:  2               HeI5876      4.045      0.20     -45    47
# Comp:  2          [OIII]5007_d      60.31      0.25     -45    47
# Comp:  2            [OI]6300_d      2.521      0.25     -45    47
# Comp:  2           [NII]6583_d      22.31      0.25     -45    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        84         1
#  comp.  1:       -53        24
#  comp.  2:       -50        41
# chi2/DOF: 1.792; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.32      0.18     -53    24
# Comp:  1                Halpha      91.18      0.18     -53    24
# Comp:  2             [SII]6716      18.08      0.19     -50    41
# Comp:  2             [SII]6731      11.61      0.19     -50    41
# Comp:  2              HeII4687     0.1890      0.19     -50    41
# Comp:  2               HeI5876      3.913      0.19     -50    41
# Comp:  2          [OIII]5007_d      63.20      0.24     -50    41
# Comp:  2            [OI]6300_d      1.942      0.24     -50    41
# Comp:  2           [NII]6583_d      22.01      0.24     -50    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81       189
#  comp.  1:       -50        38
#  comp.  2:       -51        30
# chi2/DOF: 1.873; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.29      0.19     -50    38
# Comp:  1                Halpha      96.06      0.19     -50    38
# Comp:  2             [SII]6716      16.23      0.19     -51    30
# Comp:  2             [SII]6731      11.62      0.19     -51    30
# Comp:  2              HeII4687      0.000      0.19     -51    30
# Comp:  2               HeI5876      3.911      0.19     -51    30
# Comp:  2          [OIII]5007_d      57.66      0.24     -51    30
# Comp:  2            [OI]6300_d      2.293      0.24     -51    30
# Comp:  2           [NII]6583_d      21.41      0.24     -51    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       116
#  comp.  1:       -55        26
#  comp.  2:       -50        20
# chi2/DOF: 1.841; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.42      0.18     -55    26
# Comp:  1                Halpha      92.13      0.18     -55    26
# Comp:  2             [SII]6716      16.07      0.18     -50    20
# Comp:  2             [SII]6731      11.18      0.18     -50    20
# Comp:  2              HeII4687     0.1895      0.18     -50    20
# Comp:  2               HeI5876      3.706      0.18     -50    20
# Comp:  2          [OIII]5007_d      55.81      0.23     -50    20
# Comp:  2            [OI]6300_d      2.219      0.23     -50    20
# Comp:  2           [NII]6583_d      20.30      0.23     -50    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123       133
#  comp.  1:       -52        39
#  comp.  2:       -52        31
# chi2/DOF: 1.763; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.03      0.19     -52    39
# Comp:  1                Halpha      96.45      0.19     -52    39
# Comp:  2             [SII]6716      16.05      0.19     -52    31
# Comp:  2             [SII]6731      11.57      0.19     -52    31
# Comp:  2              HeII4687      0.000      0.19     -52    31
# Comp:  2               HeI5876      4.147      0.19     -52    31
# Comp:  2          [OIII]5007_d      55.38      0.24     -52    31
# Comp:  2            [OI]6300_d      1.854      0.24     -52    31
# Comp:  2           [NII]6583_d      20.78      0.24     -52    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60       113
#  comp.  1:       -55        29
#  comp.  2:       -58        32
# chi2/DOF: 1.852; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.73      0.19     -55    29
# Comp:  1                Halpha      92.71      0.19     -55    29
# Comp:  2             [SII]6716      17.07      0.19     -58    32
# Comp:  2             [SII]6731      12.67      0.19     -58    32
# Comp:  2              HeII4687      0.000      0.19     -58    32
# Comp:  2               HeI5876      3.761      0.19     -58    32
# Comp:  2          [OIII]5007_d      60.37      0.24     -58    32
# Comp:  2            [OI]6300_d      1.946      0.24     -58    32
# Comp:  2           [NII]6583_d      19.81      0.24     -58    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55         1
#  comp.  1:       -52        34
#  comp.  2:       -50        42
# chi2/DOF: 1.905; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.75      0.19     -52    34
# Comp:  1                Halpha      94.78      0.19     -52    34
# Comp:  2             [SII]6716      17.64      0.19     -50    42
# Comp:  2             [SII]6731      11.67      0.19     -50    42
# Comp:  2              HeII4687      0.000      0.19     -50    42
# Comp:  2               HeI5876      4.142      0.19     -50    42
# Comp:  2          [OIII]5007_d      63.53      0.24     -50    42
# Comp:  2            [OI]6300_d      2.031      0.24     -50    42
# Comp:  2           [NII]6583_d      21.58      0.24     -50    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21       117
#  comp.  1:       -54        21
#  comp.  2:       -50        27
# chi2/DOF: 1.689; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.91      0.18     -54    21
# Comp:  1                Halpha      90.41      0.18     -54    21
# Comp:  2             [SII]6716      16.17      0.18     -50    27
# Comp:  2             [SII]6731      10.15      0.18     -50    27
# Comp:  2              HeII4687      0.000      0.18     -50    27
# Comp:  2               HeI5876      3.716      0.18     -50    27
# Comp:  2          [OIII]5007_d      58.96      0.23     -50    27
# Comp:  2            [OI]6300_d      1.938      0.23     -50    27
# Comp:  2           [NII]6583_d      20.71      0.23     -50    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       229
#  comp.  1:       -52        27
#  comp.  2:       -47        38
# chi2/DOF: 1.997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.20      0.18     -52    27
# Comp:  1                Halpha      91.60      0.18     -52    27
# Comp:  2             [SII]6716      16.04      0.19     -47    38
# Comp:  2             [SII]6731      10.81      0.19     -47    38
# Comp:  2              HeII4687    0.01118      0.19     -47    38
# Comp:  2               HeI5876      3.959      0.19     -47    38
# Comp:  2          [OIII]5007_d      63.04      0.24     -47    38
# Comp:  2            [OI]6300_d      1.783      0.24     -47    38
# Comp:  2           [NII]6583_d      21.84      0.24     -47    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       199
#  comp.  1:       -55        26
#  comp.  2:       -52        13
# chi2/DOF: 1.761; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.04      0.18     -55    26
# Comp:  1                Halpha      91.19      0.18     -55    26
# Comp:  2             [SII]6716      16.93      0.18     -52    13
# Comp:  2             [SII]6731      10.98      0.18     -52    13
# Comp:  2              HeII4687     0.1342      0.18     -52    13
# Comp:  2               HeI5876      3.675      0.18     -52    13
# Comp:  2          [OIII]5007_d      54.77      0.23     -52    13
# Comp:  2            [OI]6300_d      1.598      0.23     -52    13
# Comp:  2           [NII]6583_d      19.80      0.23     -52    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        51
#  comp.  1:       -52        37
#  comp.  2:       -47        38
# chi2/DOF: 1.830; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.27      0.19     -52    37
# Comp:  1                Halpha      95.60      0.19     -52    37
# Comp:  2             [SII]6716      16.55      0.19     -47    38
# Comp:  2             [SII]6731      10.51      0.19     -47    38
# Comp:  2              HeII4687      0.000      0.19     -47    38
# Comp:  2               HeI5876      4.047      0.19     -47    38
# Comp:  2          [OIII]5007_d      63.09      0.24     -47    38
# Comp:  2            [OI]6300_d      1.742      0.24     -47    38
# Comp:  2           [NII]6583_d      21.55      0.24     -47    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127       181
#  comp.  1:       -54        27
#  comp.  2:       -47        17
# chi2/DOF: 1.778; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.13      0.18     -54    27
# Comp:  1                Halpha      91.91      0.18     -54    27
# Comp:  2             [SII]6716      17.01      0.18     -47    17
# Comp:  2             [SII]6731      11.03      0.18     -47    17
# Comp:  2              HeII4687      0.000      0.18     -47    17
# Comp:  2               HeI5876      3.489      0.18     -47    17
# Comp:  2          [OIII]5007_d      57.35      0.23     -47    17
# Comp:  2            [OI]6300_d      2.481      0.23     -47    17
# Comp:  2           [NII]6583_d      20.90      0.23     -47    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       128
#  comp.  1:       -54        28
#  comp.  2:       -53        45
# chi2/DOF: 1.868; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.33      0.19     -54    28
# Comp:  1                Halpha      92.43      0.19     -54    28
# Comp:  2             [SII]6716      15.62      0.20     -53    45
# Comp:  2             [SII]6731      13.07      0.20     -53    45
# Comp:  2              HeII4687   0.002033      0.20     -53    45
# Comp:  2               HeI5876      3.467      0.20     -53    45
# Comp:  2          [OIII]5007_d      62.49      0.25     -53    45
# Comp:  2            [OI]6300_d      2.118      0.25     -53    45
# Comp:  2           [NII]6583_d      22.37      0.25     -53    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63         1
#  comp.  1:       -55        25
#  comp.  2:       -49        32
# chi2/DOF: 1.881; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.61      0.18     -55    25
# Comp:  1                Halpha      91.77      0.18     -55    25
# Comp:  2             [SII]6716      16.51      0.19     -49    32
# Comp:  2             [SII]6731      12.87      0.19     -49    32
# Comp:  2              HeII4687     0.1663      0.19     -49    32
# Comp:  2               HeI5876      3.991      0.19     -49    32
# Comp:  2          [OIII]5007_d      60.32      0.24     -49    32
# Comp:  2            [OI]6300_d      2.446      0.24     -49    32
# Comp:  2           [NII]6583_d      22.18      0.24     -49    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       123
#  comp.  1:       -55        27
#  comp.  2:       -57        33
# chi2/DOF: 1.897; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.37      0.18     -55    27
# Comp:  1                Halpha      91.28      0.18     -55    27
# Comp:  2             [SII]6716      16.52      0.19     -57    33
# Comp:  2             [SII]6731      11.54      0.19     -57    33
# Comp:  2              HeII4687     0.1217      0.19     -57    33
# Comp:  2               HeI5876      3.848      0.19     -57    33
# Comp:  2          [OIII]5007_d      60.48      0.24     -57    33
# Comp:  2            [OI]6300_d      2.240      0.24     -57    33
# Comp:  2           [NII]6583_d      21.20      0.24     -57    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180        61
#  comp.  1:       -52        38
#  comp.  2:       -47        40
# chi2/DOF: 1.794; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.94      0.19     -52    38
# Comp:  1                Halpha      96.55      0.19     -52    38
# Comp:  2             [SII]6716      16.48      0.19     -47    40
# Comp:  2             [SII]6731      12.08      0.19     -47    40
# Comp:  2              HeII4687      0.000      0.19     -47    40
# Comp:  2               HeI5876      3.557      0.19     -47    40
# Comp:  2          [OIII]5007_d      61.23      0.24     -47    40
# Comp:  2            [OI]6300_d      2.445      0.24     -47    40
# Comp:  2           [NII]6583_d      20.80      0.24     -47    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       108
#  comp.  1:       -55        28
#  comp.  2:       -55        32
# chi2/DOF: 1.903; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.79      0.19     -55    28
# Comp:  1                Halpha      92.54      0.19     -55    28
# Comp:  2             [SII]6716      17.51      0.19     -55    32
# Comp:  2             [SII]6731      11.47      0.19     -55    32
# Comp:  2              HeII4687     0.2322      0.19     -55    32
# Comp:  2               HeI5876      3.795      0.19     -55    32
# Comp:  2          [OIII]5007_d      62.08      0.24     -55    32
# Comp:  2            [OI]6300_d      2.196      0.24     -55    32
# Comp:  2           [NII]6583_d      21.70      0.24     -55    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25       253
#  comp.  1:       -51        36
#  comp.  2:       -49        50
# chi2/DOF: 1.548; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.81      0.19     -51    36
# Comp:  1                Halpha      94.86      0.19     -51    36
# Comp:  2             [SII]6716      18.91      0.20     -49    50
# Comp:  2             [SII]6731      11.09      0.20     -49    50
# Comp:  2              HeII4687      0.000      0.20     -49    50
# Comp:  2               HeI5876      3.912      0.20     -49    50
# Comp:  2          [OIII]5007_d      66.14      0.25     -49    50
# Comp:  2            [OI]6300_d      1.755      0.25     -49    50
# Comp:  2           [NII]6583_d      21.66      0.25     -49    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        83
#  comp.  1:       -54        23
#  comp.  2:       -51        41
# chi2/DOF: 1.688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.63      0.18     -54    23
# Comp:  1                Halpha      90.85      0.18     -54    23
# Comp:  2             [SII]6716      15.44      0.19     -51    41
# Comp:  2             [SII]6731      11.80      0.19     -51    41
# Comp:  2              HeII4687     0.1229      0.19     -51    41
# Comp:  2               HeI5876      4.017      0.19     -51    41
# Comp:  2          [OIII]5007_d      65.93      0.24     -51    41
# Comp:  2            [OI]6300_d      2.224      0.24     -51    41
# Comp:  2           [NII]6583_d      21.58      0.24     -51    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        66         1
#  comp.  1:       -56        28
#  comp.  2:       -53        44
# chi2/DOF: 1.690; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.95      0.18     -56    28
# Comp:  1                Halpha      92.94      0.18     -56    28
# Comp:  2             [SII]6716      16.84      0.19     -53    44
# Comp:  2             [SII]6731      10.96      0.19     -53    44
# Comp:  2              HeII4687      0.000      0.19     -53    44
# Comp:  2               HeI5876      3.967      0.19     -53    44
# Comp:  2          [OIII]5007_d      64.78      0.25     -53    44
# Comp:  2            [OI]6300_d      2.097      0.25     -53    44
# Comp:  2           [NII]6583_d      22.93      0.25     -53    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81       150
#  comp.  1:       -55        28
#  comp.  2:       -51        29
# chi2/DOF: 2.003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.53      0.18     -55    28
# Comp:  1                Halpha      92.32      0.18     -55    28
# Comp:  2             [SII]6716      16.54      0.19     -51    29
# Comp:  2             [SII]6731      12.51      0.19     -51    29
# Comp:  2              HeII4687      0.000      0.19     -51    29
# Comp:  2               HeI5876      3.506      0.19     -51    29
# Comp:  2          [OIII]5007_d      57.00      0.23     -51    29
# Comp:  2            [OI]6300_d      2.387      0.23     -51    29
# Comp:  2           [NII]6583_d      20.92      0.23     -51    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98       145
#  comp.  1:       -54        29
#  comp.  2:       -48        43
# chi2/DOF: 1.964; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      30.31      0.19     -54    29
# Comp:  1                Halpha      92.76      0.19     -54    29
# Comp:  2             [SII]6716      16.78      0.19     -48    43
# Comp:  2             [SII]6731      12.09      0.19     -48    43
# Comp:  2              HeII4687      0.000      0.19     -48    43
# Comp:  2               HeI5876      3.921      0.19     -48    43
# Comp:  2          [OIII]5007_d      61.57      0.25     -48    43
# Comp:  2            [OI]6300_d      1.954      0.25     -48    43
# Comp:  2           [NII]6583_d      21.25      0.25     -48    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:       -54        21
#  comp.  2:       -54        23
# chi2/DOF: 1.652; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.84      0.18     -54    21
# Comp:  1                Halpha      90.71      0.18     -54    21
# Comp:  2             [SII]6716      15.40      0.18     -54    23
# Comp:  2             [SII]6731      11.38      0.18     -54    23
# Comp:  2              HeII4687      0.000      0.18     -54    23
# Comp:  2               HeI5876      3.842      0.18     -54    23
# Comp:  2          [OIII]5007_d      60.19      0.23     -54    23
# Comp:  2            [OI]6300_d      2.155      0.23     -54    23
# Comp:  2           [NII]6583_d      20.88      0.23     -54    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45       156
#  comp.  1:       -51        35
#  comp.  2:       -49        38
# chi2/DOF: 2.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.91      0.19     -51    35
# Comp:  1                Halpha      94.45      0.19     -51    35
# Comp:  2             [SII]6716      16.25      0.19     -49    38
# Comp:  2             [SII]6731      13.17      0.19     -49    38
# Comp:  2              HeII4687      0.000      0.19     -49    38
# Comp:  2               HeI5876      3.592      0.19     -49    38
# Comp:  2          [OIII]5007_d      60.48      0.24     -49    38
# Comp:  2            [OI]6300_d      1.953      0.24     -49    38
# Comp:  2           [NII]6583_d      21.72      0.24     -49    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        92
#  comp.  1:       -52        25
#  comp.  2:       -47        41
# chi2/DOF: 1.783; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.16      0.18     -52    25
# Comp:  1                Halpha      91.50      0.18     -52    25
# Comp:  2             [SII]6716      17.88      0.19     -47    41
# Comp:  2             [SII]6731      12.85      0.19     -47    41
# Comp:  2              HeII4687      0.000      0.19     -47    41
# Comp:  2               HeI5876      3.704      0.19     -47    41
# Comp:  2          [OIII]5007_d      65.46      0.24     -47    41
# Comp:  2            [OI]6300_d      1.844      0.24     -47    41
# Comp:  2           [NII]6583_d      21.81      0.24     -47    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146       121
#  comp.  1:       -54        24
#  comp.  2:       -47        41
# chi2/DOF: 1.801; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.40      0.18     -54    24
# Comp:  1                Halpha      90.99      0.18     -54    24
# Comp:  2             [SII]6716      17.92      0.19     -47    41
# Comp:  2             [SII]6731      10.55      0.19     -47    41
# Comp:  2              HeII4687    0.03829      0.19     -47    41
# Comp:  2               HeI5876      3.628      0.19     -47    41
# Comp:  2          [OIII]5007_d      65.62      0.24     -47    41
# Comp:  2            [OI]6300_d      2.155      0.24     -47    41
# Comp:  2           [NII]6583_d      21.42      0.24     -47    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119         1
#  comp.  1:       -52        26
#  comp.  2:       -42        37
# chi2/DOF: 1.808; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.16      0.18     -52    26
# Comp:  1                Halpha      91.33      0.18     -52    26
# Comp:  2             [SII]6716      18.14      0.19     -42    37
# Comp:  2             [SII]6731      11.57      0.19     -42    37
# Comp:  2              HeII4687      0.000      0.19     -42    37
# Comp:  2               HeI5876      3.925      0.19     -42    37
# Comp:  2          [OIII]5007_d      60.32      0.24     -42    37
# Comp:  2            [OI]6300_d      2.049      0.24     -42    37
# Comp:  2           [NII]6583_d      21.48      0.24     -42    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65       155
#  comp.  1:       -55        26
#  comp.  2:       -50        26
# chi2/DOF: 1.953; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.56      0.18     -55    26
# Comp:  1                Halpha      91.82      0.18     -55    26
# Comp:  2             [SII]6716      15.48      0.18     -50    26
# Comp:  2             [SII]6731      10.22      0.18     -50    26
# Comp:  2              HeII4687     0.2163      0.18     -50    26
# Comp:  2               HeI5876      3.860      0.18     -50    26
# Comp:  2          [OIII]5007_d      56.64      0.23     -50    26
# Comp:  2            [OI]6300_d      1.832      0.23     -50    26
# Comp:  2           [NII]6583_d      20.17      0.23     -50    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -131       140
#  comp.  1:       -52        36
#  comp.  2:       -53        27
# chi2/DOF: 1.826; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.45      0.19     -52    36
# Comp:  1                Halpha      94.57      0.19     -52    36
# Comp:  2             [SII]6716      17.38      0.18     -53    27
# Comp:  2             [SII]6731      12.50      0.18     -53    27
# Comp:  2              HeII4687      0.000      0.18     -53    27
# Comp:  2               HeI5876      3.840      0.18     -53    27
# Comp:  2          [OIII]5007_d      60.67      0.23     -53    27
# Comp:  2            [OI]6300_d      2.440      0.23     -53    27
# Comp:  2           [NII]6583_d      20.32      0.23     -53    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       114
#  comp.  1:       -54        36
#  comp.  2:       -44        28
# chi2/DOF: 1.757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.27      0.19     -54    36
# Comp:  1                Halpha      95.55      0.19     -54    36
# Comp:  2             [SII]6716      14.45      0.18     -44    28
# Comp:  2             [SII]6731      10.19      0.18     -44    28
# Comp:  2              HeII4687      0.000      0.18     -44    28
# Comp:  2               HeI5876      3.285      0.18     -44    28
# Comp:  2          [OIII]5007_d      60.44      0.23     -44    28
# Comp:  2            [OI]6300_d      1.839      0.23     -44    28
# Comp:  2           [NII]6583_d      21.07      0.23     -44    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68        98
#  comp.  1:       -53        24
#  comp.  2:       -49        48
# chi2/DOF: 1.770; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.74      0.18     -53    24
# Comp:  1                Halpha      91.06      0.18     -53    24
# Comp:  2             [SII]6716      17.23      0.20     -49    48
# Comp:  2             [SII]6731      11.98      0.20     -49    48
# Comp:  2              HeII4687      0.000      0.20     -49    48
# Comp:  2               HeI5876      3.609      0.20     -49    48
# Comp:  2          [OIII]5007_d      65.83      0.25     -49    48
# Comp:  2            [OI]6300_d      2.216      0.25     -49    48
# Comp:  2           [NII]6583_d      22.00      0.25     -49    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10       204
#  comp.  1:       -53        24
#  comp.  2:       -44        31
# chi2/DOF: 1.790; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      29.56      0.18     -53    24
# Comp:  1                Halpha      90.58      0.18     -53    24
# Comp:  2             [SII]6716      16.05      0.19     -44    31
# Comp:  2             [SII]6731      11.43      0.19     -44    31
# Comp:  2              HeII4687      0.000      0.19     -44    31
# Comp:  2               HeI5876      3.736      0.19     -44    31
# Comp:  2          [OIII]5007_d      58.74      0.24     -44    31
# Comp:  2            [OI]6300_d      1.674      0.24     -44    31
# Comp:  2           [NII]6583_d      21.68      0.24     -44    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85       100
#  comp.  1:       -51        37
#  comp.  2:       -49        48
# chi2/DOF: 1.589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.67      0.19     -51    37
# Comp:  1                Halpha      94.63      0.19     -51    37
# Comp:  2             [SII]6716      16.78      0.20     -49    48
# Comp:  2             [SII]6731      11.05      0.20     -49    48
# Comp:  2              HeII4687      0.000      0.20     -49    48
# Comp:  2               HeI5876      3.943      0.20     -49    48
# Comp:  2          [OIII]5007_d      65.51      0.25     -49    48
# Comp:  2            [OI]6300_d      1.939      0.25     -49    48
# Comp:  2           [NII]6583_d      23.28      0.25     -49    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:       -52        38
#  comp.  2:       -43        39
# chi2/DOF: 1.707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.32      0.19     -52    38
# Comp:  1                Halpha      96.18      0.19     -52    38
# Comp:  2             [SII]6716      16.98      0.19     -43    39
# Comp:  2             [SII]6731      11.70      0.19     -43    39
# Comp:  2              HeII4687      0.000      0.19     -43    39
# Comp:  2               HeI5876      3.915      0.19     -43    39
# Comp:  2          [OIII]5007_d      58.54      0.24     -43    39
# Comp:  2            [OI]6300_d      2.056      0.24     -43    39
# Comp:  2           [NII]6583_d      20.98      0.24     -43    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73         1
#  comp.  1:       -56        29
#  comp.  2:       -49        46
# chi2/DOF: 1.585; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.19      0.19     -56    29
# Comp:  1                Halpha      93.51      0.19     -56    29
# Comp:  2             [SII]6716      15.37      0.20     -49    46
# Comp:  2             [SII]6731      12.20      0.20     -49    46
# Comp:  2              HeII4687      0.000      0.20     -49    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.94      0.19     -51    31
# Comp:  1                Halpha      93.24      0.19     -51    31
# Comp:  2             [SII]6716      14.68      0.18     -53    20
# Comp:  2             [SII]6731      11.00      0.18     -53    20
# Comp:  2              HeII4687    0.08964      0.18     -53    20
# Comp:  2               HeI5876      3.703      0.18     -53    20
# Comp:  2          [OIII]5007_d      59.77      0.23     -53    20
# Comp:  2            [OI]6300_d      2.177      0.23     -53    20
# Comp:  2           [NII]6583_d      20.46      0.23     -53    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50       101
#  comp.  1:       -52        38
#  comp.  2:       -42        35
# chi2/DOF: 1.773; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.59      0.19     -52    38
# Comp:  1                Halpha      96.14      0.19     -52    38
# Comp:  2             [SII]6716      16.20      0.19     -42    35
# Comp:  2             [SII]6731      11.44      0.19     -42    35
# Comp:  2              HeII4687     0.2266      0.19     -42    35
# Comp:  2               HeI5876      3.661      0.19     -42    35
# Comp:  2          [OIII]5007_d      61.97      0.24     -42    35
# Comp:  2            [OI]6300_d      2.389      0.24     -42    35
# Comp:  2           [NII]6583_d      21.40      0.24     -42    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78       176
#  comp.  1:       -54        27
#  comp.  2:       -48        43
# chi2/DOF: 1.985; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.39      0.18     -54    27
# Comp:  1                Halpha      92.17      0.18     -54    27
# Comp:  2             [SII]6716      15.95      0.19     -48    43
# Comp:  2             [SII]6731      12.23      0.19     -48    43
# Comp:  2              HeII4687      0.000      0.19     -48    43
# Comp:  2               HeI5876      4.227      0.19     -48    43
# Comp:  2          [OIII]5007_d      62.21      0.24     -48    43
# Comp:  2            [OI]6300_d      2.321      0.24     -48    43
# Comp:  2           [NII]6583_d      21.29      0.24     -48    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       110
#  comp.  1:       -54        28
#  comp.  2:       -55        31
# chi2/DOF: 1.919; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.69      0.18     -54    28
# Comp:  1                Halpha      92.64      0.18     -54    28
# Comp:  2             [SII]6716      15.90      0.19     -55    31
# Comp:  2             [SII]6731      12.45      0.19     -55    31
# Comp:  2              HeII4687      0.000      0.19     -55    31
# Comp:  2               HeI5876      3.686      0.19     -55    31
# Comp:  2          [OIII]5007_d      57.37      0.24     -55    31
# Comp:  2            [OI]6300_d      2.003      0.24     -55    31
# Comp:  2           [NII]6583_d      21.02      0.24     -55    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        66         1
#  comp.  1:       -55        26
#  comp.  2:       -51        24
# chi2/DOF: 1.808; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.80      0.18     -55    26
# Comp:  1                Halpha      92.35      0.18     -55    26
# Comp:  2             [SII]6716      16.14      0.18     -51    24
# Comp:  2             [SII]6731      12.19      0.18     -51    24
# Comp:  2              HeII4687      0.000      0.18     -51    24
# Comp:  2               HeI5876      3.401      0.18     -51    24
# Comp:  2          [OIII]5007_d      56.24      0.23     -51    24
# Comp:  2            [OI]6300_d      2.023      0.23     -51    24
# Comp:  2           [NII]6583_d      20.63      0.23     -51    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68         1
#  comp.  1:       -55        26
#  comp.  2:       -51        22
# chi2/DOF: 1.633; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.95      0.18     -55    26
# Comp:  1                Halpha      92.09      0.18     -55    26
# Comp:  2             [SII]6716      14.66      0.18     -51    22
# Comp:  2             [SII]6731      12.21      0.18     -51    22
# Comp:  2              HeII4687      0.000      0.18     -51    22
# Comp:  2               HeI5876      3.645      0.18     -51    22
# Comp:  2          [OIII]5007_d      54.09      0.23     -51    22
# Comp:  2            [OI]6300_d      1.453      0.23     -51    22
# Comp:  2           [NII]6583_d      19.67      0.23     -51    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113       213
#  comp.  1:       -54        25
#  comp.  2:       -44        34
# chi2/DOF: 1.894; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      33.42      0.18     -54    25
# Comp:  1                Halpha      90.81      0.18     -54    25
# Comp:  2             [SII]6716      14.95      0.19     -44    34
# Comp:  2             [SII]6731      11.64      0.19     -44    34
# Comp:  2              HeII4687    0.01475      0.19     -44    34
# Comp:  2               HeI5876      3.598      0.19     -44    34
# Comp:  2          [OIII]5007_d      59.39      0.24     -44    34
# Comp:  2            [OI]6300_d      1.915      0.24     -44    34
# Comp:  2           [NII]6583_d      20.21      0.24     -44    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35         1
#  comp.  1:       -53        36
#  comp.  2:       -57        33
# chi2/DOF: 1.854; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.59      0.19     -53    36
# Comp:  1                Halpha      96.17      0.19     -53    36
# Comp:  2             [SII]6716      16.37      0.19     -57    33
# Comp:  2             [SII]6731      11.34      0.19     -57    33
# Comp:  2              HeII4687      0.000      0.19     -57    33
# Comp:  2               HeI5876      4.173      0.19     -57    33
# Comp:  2          [OIII]5007_d      58.49      0.24     -57    33
# Comp:  2            [OI]6300_d      1.745      0.24     -57    33
# Comp:  2           [NII]6583_d      21.06      0.24     -57    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41       175
#  comp.  1:       -56        31
#  comp.  2:       -45        47
# chi2/DOF: 1.810; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.60      0.19     -56    31
# Comp:  1                Halpha      93.12      0.19     -56    31
# Comp:  2             [SII]6716      17.24      0.20     -45    47
# Comp:  2             [SII]6731      13.32      0.20     -45    47
# Comp:  2              HeII4687      0.000      0.20     -45    47
# Comp:  2               HeI5876      3.828      0.20     -45    47
# Comp:  2          [OIII]5007_d      60.59      0.25     -45    47
# Comp:  2            [OI]6300_d      1.841      0.25     -45    47
# Comp:  2           [NII]6583_d      22.09      0.25     -45    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15       130
#  comp.  1:       -54        36
#  comp.  2:       -48        26
# chi2/DOF: 1.847; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      31.04      0.19     -54    36
# Comp:  1                Halpha      95.38      0.19     -54    36
# Comp:  2             [SII]6716      16.91      0.18     -48    26
# Comp:  2             [SII]6731      11.37      0.18     -48    26
# Comp:  2              HeII4687    0.02024      0.18     -48    26
# Comp:  2               HeI5876      3.266      0.18     -48    26
# Comp:  2          [OIII]5007_d      56.69      0.23     -48    26
# Comp:  2            [OI]6300_d      2.052      0.23     -48    26
# Comp:  2           [NII]6583_d      20.67      0.23     -48    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5       129
#  comp.  1:       -53        28
#  comp.  2:       -56        21
# chi2/DOF: 1.862; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      32.81      0.19     -53    28
# Comp:  1                Halpha      91.67      0.19     -53    28
# Comp:  2             [SII]6716      15.93      0.18     -56    21
# Comp:  2             [SII]6731      12.40      0.18     -56    21
# Comp:  2              HeII4687      0.000      0.18     -56    21
# Comp:  2               HeI5876      3.317      0.18     -56    21
# Comp:  2          [OIII]5007_d      58.23      0.23     -56    21
# Comp:  2            [OI]6300_d      1.923      0.23     -56    21
# Comp:  2           [NII]6583_d      19.90      0.23     -56    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        88         4
#  comp.  1:       -54        26
#  comp.  2:       -49        15
# chi2/DOF: 1.697; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.18      0.18     -54    26
# Comp:  1                Halpha      91.71      0.18     -54    26
# Comp:  2             [SII]6716      15.75      0.18     -49    15
# Comp:  2             [SII]6731      10.88      0.18     -49    15
# Comp:  2              HeII4687      0.000      0.18     -49    15
# Comp:  2               HeI5876      3.160      0.18     -49    15
# Comp:  2          [OIII]5007_d      55.03      0.23     -49    15
# Comp:  2            [OI]6300_d      1.916      0.23     -49    15
# Comp:  2           [NII]6583_d      19.94      0.23     -49    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31       191
#  comp.  1:       -54        28
#  comp.  2:       -52        29
# chi2/DOF: 1.742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.54      0.19     -54    28
# Comp:  1                Halpha      91.67      0.19     -54    28
# Comp:  2             [SII]6716      15.86      0.19     -52    29
# Comp:  2             [SII]6731      10.27      0.19     -52    29
# Comp:  2              HeII4687     0.2540      0.19     -52    29
# Comp:  2               HeI5876      3.199      0.19     -52    29
# Comp:  2          [OIII]5007_d      55.03      0.23     -52    29
# Comp:  2            [OI]6300_d      2.507      0.23     -52    29
# Comp:  2           [NII]6583_d      21.25      0.23     -52    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62       132
#  comp.  1:       -54        38
#  comp.  2:       -57        40
# chi2/DOF: 1.729; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.62      0.19     -54    38
# Comp:  1                Halpha      95.85      0.19     -54    38
# Comp:  2             [SII]6716      18.15      0.19     -57    40
# Comp:  2             [SII]6731      13.22      0.19     -57    40
# Comp:  2              HeII4687      0.000      0.19     -57    40
# Comp:  2               HeI5876      3.867      0.19     -57    40
# Comp:  2          [OIII]5007_d      59.80      0.24     -57    40
# Comp:  2            [OI]6300_d      2.536      0.24     -57    40
# Comp:  2           [NII]6583_d      20.43      0.24     -57    40
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.35754452, 2.60862058, 1.42942891, 1.22643718, 0.07885316,
#        0.31139547, 3.34082595, 0.35769196, 1.1261031 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 33.61579134, 127.44314958,  22.96876967,  16.33924617,
#          0.        ,   4.57082963,  62.8343523 ,   2.68312003,
#         29.25539377])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_17_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_17", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_17_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_17_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_17_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  2.241661    0.157212
# 1        Halpha  8.498515    0.173955
# 2     [SII]6716  1.531667    0.095321
# 3     [SII]6731  1.089579    0.081785
# 4      HeII4687  0.000000    0.005258
# 5       HeI5876  0.304805    0.020765
# 6  [OIII]5007_d  4.190093    0.222782
# 7    [OI]6300_d  0.178923    0.023853
# 8   [NII]6583_d  1.950889    0.075094
#           Name      Flux  Error_flux
# 0        Hbeta  2.241661    0.157212
# 1       Halpha  8.498515    0.173955
# 2    [SII]6716  1.531667    0.095321
# 3    [SII]6731  1.089579    0.081785
# 4     HeII4687  0.000000    0.005258
# 5      HeI5876  0.304805    0.020765
# 6   [OIII]4959  1.047523    0.222782
# 7   [OIII]5007  3.142570    0.222782
# 8     [OI]6300  0.134192    0.023853
# 9     [OI]6364  0.044731    0.023853
# 10   [NII]6548  0.487722    0.075094
# 11   [NII]6583  1.463166    0.075094

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06668475018478456
