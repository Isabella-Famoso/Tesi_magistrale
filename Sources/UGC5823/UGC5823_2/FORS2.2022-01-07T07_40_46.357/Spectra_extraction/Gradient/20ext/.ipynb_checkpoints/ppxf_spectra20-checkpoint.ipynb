# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_20.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_20']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.00855468 0.02333098 0.01587887 ... 0.01236199 0.0164279  0.01556431] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        25
# chi2/DOF: 0.08339; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        17        16
# chi2/DOF: 0.04556; DOF: 1905; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([17.32127454, 16.07332271])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        41
#  comp.  1:       -49        44
#  comp.  2:       -58         1
# chi2/DOF: 0.6630; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.936      0.72     -49    44
# Comp:  1                Halpha      16.89      0.72     -49    44
# Comp:  2             [SII]6716      6.371      0.66     -58     1
# Comp:  2             [SII]6731      4.599      0.66     -58     1
# Comp:  2              HeII4687    0.02488      0.66     -58     1
# Comp:  2               HeI5876      1.218      0.66     -58     1
# Comp:  2          [OIII]5007_d      9.482      0.83     -58     1
# Comp:  2            [OI]6300_d      3.386      0.83     -58     1
# Comp:  2           [NII]6583_d      5.064      0.83     -58     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  12.69; gas flux:      9 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  23.44; gas flux:     23 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.888; gas flux:      9 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  7.631; gas flux:      6 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.04114; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.039; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  12.16; gas flux:     10 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.303; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  6.069; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         3        53
#  comp.  1:       -47        50
#  comp.  2:       -56         1
# chi2/DOF: 0.6575; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.41      0.74     -47    50
# Comp:  1                Halpha      17.75      0.74     -47    50
# Comp:  2             [SII]6716      6.347      0.66     -56     1
# Comp:  2             [SII]6731      4.694      0.66     -56     1
# Comp:  2              HeII4687     0.1927      0.66     -56     1
# Comp:  2               HeI5876     0.9206      0.66     -56     1
# Comp:  2          [OIII]5007_d      9.431      0.83     -56     1
# Comp:  2            [OI]6300_d      2.901      0.83     -56     1
# Comp:  2           [NII]6583_d      5.232      0.83     -56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -49        42
#  comp.  2:       -59        18
# chi2/DOF: 0.6578; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.994      0.72     -49    42
# Comp:  1                Halpha      17.00      0.72     -49    42
# Comp:  2             [SII]6716      6.983      0.67     -59    18
# Comp:  2             [SII]6731      4.602      0.67     -59    18
# Comp:  2              HeII4687      0.000      0.67     -59    18
# Comp:  2               HeI5876      1.583      0.67     -59    18
# Comp:  2          [OIII]5007_d      9.707      0.85     -59    18
# Comp:  2            [OI]6300_d      3.313      0.85     -59    18
# Comp:  2           [NII]6583_d      5.023      0.85     -59    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        54
#  comp.  1:       -48        46
#  comp.  2:       -57         1
# chi2/DOF: 0.6569; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.790      0.73     -48    46
# Comp:  1                Halpha      17.27      0.73     -48    46
# Comp:  2             [SII]6716      5.793      0.66     -57     1
# Comp:  2             [SII]6731      4.839      0.66     -57     1
# Comp:  2              HeII4687     0.3446      0.66     -57     1
# Comp:  2               HeI5876      1.178      0.66     -57     1
# Comp:  2          [OIII]5007_d      8.499      0.83     -57     1
# Comp:  2            [OI]6300_d      2.840      0.83     -57     1
# Comp:  2           [NII]6583_d      5.134      0.83     -57     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         3
#  comp.  1:       -47        48
#  comp.  2:       -60         1
# chi2/DOF: 0.6539; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.077      0.73     -47    48
# Comp:  1                Halpha      17.21      0.73     -47    48
# Comp:  2             [SII]6716      6.908      0.66     -60     1
# Comp:  2             [SII]6731      4.754      0.66     -60     1
# Comp:  2              HeII4687      0.000      0.66     -60     1
# Comp:  2               HeI5876      1.309      0.66     -60     1
# Comp:  2          [OIII]5007_d      8.794      0.83     -60     1
# Comp:  2            [OI]6300_d      3.404      0.83     -60     1
# Comp:  2           [NII]6583_d      5.204      0.83     -60     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -51        46
#  comp.  2:       -60        17
# chi2/DOF: 0.6577; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.940      0.73     -51    46
# Comp:  1                Halpha      17.03      0.73     -51    46
# Comp:  2             [SII]6716      6.566      0.67     -60    17
# Comp:  2             [SII]6731      4.577      0.67     -60    17
# Comp:  2              HeII4687      0.000      0.67     -60    17
# Comp:  2               HeI5876      1.114      0.67     -60    17
# Comp:  2          [OIII]5007_d      10.29      0.85     -60    17
# Comp:  2            [OI]6300_d      3.414      0.85     -60    17
# Comp:  2           [NII]6583_d      5.247      0.85     -60    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:       -47        43
#  comp.  2:       -55        21
# chi2/DOF: 0.6578; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.666      0.72     -47    43
# Comp:  1                Halpha      17.57      0.72     -47    43
# Comp:  2             [SII]6716      6.169      0.68     -55    21
# Comp:  2             [SII]6731      4.691      0.68     -55    21
# Comp:  2              HeII4687    0.02714      0.68     -55    21
# Comp:  2               HeI5876      1.178      0.68     -55    21
# Comp:  2          [OIII]5007_d      9.269      0.85     -55    21
# Comp:  2            [OI]6300_d      3.323      0.85     -55    21
# Comp:  2           [NII]6583_d      5.487      0.85     -55    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -49        47
#  comp.  2:       -64        12
# chi2/DOF: 0.6585; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.789      0.73     -49    47
# Comp:  1                Halpha      17.51      0.73     -49    47
# Comp:  2             [SII]6716      6.780      0.67     -64    12
# Comp:  2             [SII]6731      4.882      0.67     -64    12
# Comp:  2              HeII4687      0.000      0.67     -64    12
# Comp:  2               HeI5876      1.202      0.67     -64    12
# Comp:  2          [OIII]5007_d      9.648      0.84     -64    12
# Comp:  2            [OI]6300_d      3.661      0.84     -64    12
# Comp:  2           [NII]6583_d      5.149      0.84     -64    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         6
#  comp.  1:       -51        44
#  comp.  2:       -55        34
# chi2/DOF: 0.6588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.569      0.72     -51    44
# Comp:  1                Halpha      17.02      0.72     -51    44
# Comp:  2             [SII]6716      6.918      0.70     -55    34
# Comp:  2             [SII]6731      5.049      0.70     -55    34
# Comp:  2              HeII4687     0.3631      0.70     -55    34
# Comp:  2               HeI5876      1.206      0.70     -55    34
# Comp:  2          [OIII]5007_d      9.163      0.88     -55    34
# Comp:  2            [OI]6300_d      4.029      0.88     -55    34
# Comp:  2           [NII]6583_d      5.554      0.88     -55    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         9
#  comp.  1:       -47        46
#  comp.  2:       -55         1
# chi2/DOF: 0.6600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.627      0.73     -47    46
# Comp:  1                Halpha      16.80      0.73     -47    46
# Comp:  2             [SII]6716      6.526      0.66     -55     1
# Comp:  2             [SII]6731      4.456      0.66     -55     1
# Comp:  2              HeII4687    0.01777      0.66     -55     1
# Comp:  2               HeI5876      1.068      0.66     -55     1
# Comp:  2          [OIII]5007_d      9.392      0.83     -55     1
# Comp:  2            [OI]6300_d      3.393      0.83     -55     1
# Comp:  2           [NII]6583_d      5.066      0.83     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        11
#  comp.  1:       -46        40
#  comp.  2:       -58         1
# chi2/DOF: 0.6594; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.745      0.71     -46    40
# Comp:  1                Halpha      16.83      0.71     -46    40
# Comp:  2             [SII]6716      6.440      0.66     -58     1
# Comp:  2             [SII]6731      4.841      0.66     -58     1
# Comp:  2              HeII4687    0.01758      0.66     -58     1
# Comp:  2               HeI5876      1.163      0.66     -58     1
# Comp:  2          [OIII]5007_d      9.308      0.83     -58     1
# Comp:  2            [OI]6300_d      3.323      0.83     -58     1
# Comp:  2           [NII]6583_d      4.792      0.83     -58     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        37
#  comp.  1:       -49        39
#  comp.  2:       -59         1
# chi2/DOF: 0.6604; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.250      0.71     -49    39
# Comp:  1                Halpha      16.70      0.71     -49    39
# Comp:  2             [SII]6716      6.891      0.66     -59     1
# Comp:  2             [SII]6731      4.627      0.66     -59     1
# Comp:  2              HeII4687    0.07356      0.66     -59     1
# Comp:  2               HeI5876      1.687      0.66     -59     1
# Comp:  2          [OIII]5007_d      9.522      0.83     -59     1
# Comp:  2            [OI]6300_d      3.355      0.83     -59     1
# Comp:  2           [NII]6583_d      5.173      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:       -48        48
#  comp.  2:       -62         1
# chi2/DOF: 0.6582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.245      0.73     -48    48
# Comp:  1                Halpha      17.46      0.73     -48    48
# Comp:  2             [SII]6716      6.038      0.66     -62     1
# Comp:  2             [SII]6731      4.686      0.66     -62     1
# Comp:  2              HeII4687    0.09690      0.66     -62     1
# Comp:  2               HeI5876      1.436      0.66     -62     1
# Comp:  2          [OIII]5007_d      8.581      0.83     -62     1
# Comp:  2            [OI]6300_d      3.588      0.83     -62     1
# Comp:  2           [NII]6583_d      5.091      0.83     -62     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -47        43
#  comp.  2:       -62        12
# chi2/DOF: 0.6583; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.56      0.72     -47    43
# Comp:  1                Halpha      17.19      0.72     -47    43
# Comp:  2             [SII]6716      6.446      0.67     -62    12
# Comp:  2             [SII]6731      4.836      0.67     -62    12
# Comp:  2              HeII4687     0.1770      0.67     -62    12
# Comp:  2               HeI5876      1.243      0.67     -62    12
# Comp:  2          [OIII]5007_d      9.783      0.84     -62    12
# Comp:  2            [OI]6300_d      3.128      0.84     -62    12
# Comp:  2           [NII]6583_d      5.276      0.84     -62    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        75
#  comp.  1:       -49        53
#  comp.  2:       -60        13
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.771      0.75     -49    53
# Comp:  1                Halpha      17.79      0.75     -49    53
# Comp:  2             [SII]6716      6.493      0.67     -60    13
# Comp:  2             [SII]6731      4.564      0.67     -60    13
# Comp:  2              HeII4687    0.06055      0.67     -60    13
# Comp:  2               HeI5876      1.490      0.67     -60    13
# Comp:  2          [OIII]5007_d      9.582      0.84     -60    13
# Comp:  2            [OI]6300_d      3.436      0.84     -60    13
# Comp:  2           [NII]6583_d      5.264      0.84     -60    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        70
#  comp.  1:       -48        42
#  comp.  2:       -59         1
# chi2/DOF: 0.6574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.635      0.72     -48    42
# Comp:  1                Halpha      16.70      0.72     -48    42
# Comp:  2             [SII]6716      6.712      0.66     -59     1
# Comp:  2             [SII]6731      4.238      0.66     -59     1
# Comp:  2              HeII4687      0.000      0.66     -59     1
# Comp:  2               HeI5876      1.325      0.66     -59     1
# Comp:  2          [OIII]5007_d      9.724      0.83     -59     1
# Comp:  2            [OI]6300_d      3.326      0.83     -59     1
# Comp:  2           [NII]6583_d      4.917      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        46
#  comp.  1:       -49        44
#  comp.  2:       -58        11
# chi2/DOF: 0.6592; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 13; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.100      0.72     -49    44
# Comp:  1                Halpha      16.89      0.72     -49    44
# Comp:  2             [SII]6716      5.868      0.67     -58    11
# Comp:  2             [SII]6731      4.368      0.67     -58    11
# Comp:  2              HeII4687     0.2888      0.67     -58    11
# Comp:  2               HeI5876      1.162      0.67     -58    11
# Comp:  2          [OIII]5007_d      10.37      0.84     -58    11
# Comp:  2            [OI]6300_d      3.250      0.84     -58    11
# Comp:  2           [NII]6583_d      5.115      0.84     -58    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        26
#  comp.  1:       -49        46
#  comp.  2:       -58         1
# chi2/DOF: 0.6581; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.01      0.73     -49    46
# Comp:  1                Halpha      17.02      0.73     -49    46
# Comp:  2             [SII]6716      6.514      0.66     -58     1
# Comp:  2             [SII]6731      4.658      0.66     -58     1
# Comp:  2              HeII4687      0.000      0.66     -58     1
# Comp:  2               HeI5876      1.295      0.66     -58     1
# Comp:  2          [OIII]5007_d      9.184      0.83     -58     1
# Comp:  2            [OI]6300_d      3.328      0.83     -58     1
# Comp:  2           [NII]6583_d      5.083      0.83     -58     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20       187
#  comp.  1:       -48        45
#  comp.  2:       -56         1
# chi2/DOF: 0.6545; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.177      0.73     -48    45
# Comp:  1                Halpha      16.83      0.73     -48    45
# Comp:  2             [SII]6716      6.421      0.66     -56     1
# Comp:  2             [SII]6731      4.335      0.66     -56     1
# Comp:  2              HeII4687    0.06820      0.66     -56     1
# Comp:  2               HeI5876      1.186      0.66     -56     1
# Comp:  2          [OIII]5007_d      9.951      0.83     -56     1
# Comp:  2            [OI]6300_d      3.262      0.83     -56     1
# Comp:  2           [NII]6583_d      4.968      0.83     -56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        85
#  comp.  1:       -47        47
#  comp.  2:       -54        16
# chi2/DOF: 0.6576; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.488      0.73     -47    47
# Comp:  1                Halpha      17.01      0.73     -47    47
# Comp:  2             [SII]6716      6.987      0.67     -54    16
# Comp:  2             [SII]6731      4.663      0.67     -54    16
# Comp:  2              HeII4687    0.06954      0.67     -54    16
# Comp:  2               HeI5876      1.253      0.67     -54    16
# Comp:  2          [OIII]5007_d      10.28      0.85     -54    16
# Comp:  2            [OI]6300_d      3.786      0.85     -54    16
# Comp:  2           [NII]6583_d      5.017      0.85     -54    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        70
#  comp.  1:       -48        43
#  comp.  2:       -60        16
# chi2/DOF: 0.6593; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.377      0.72     -48    43
# Comp:  1                Halpha      16.68      0.72     -48    43
# Comp:  2             [SII]6716      6.012      0.67     -60    16
# Comp:  2             [SII]6731      4.990      0.67     -60    16
# Comp:  2              HeII4687      0.000      0.67     -60    16
# Comp:  2               HeI5876     0.8824      0.67     -60    16
# Comp:  2          [OIII]5007_d      9.003      0.85     -60    16
# Comp:  2            [OI]6300_d      3.440      0.85     -60    16
# Comp:  2           [NII]6583_d      5.198      0.85     -60    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        36
#  comp.  1:       -49        45
#  comp.  2:       -56         1
# chi2/DOF: 0.6586; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.968      0.73     -49    45
# Comp:  1                Halpha      17.34      0.73     -49    45
# Comp:  2             [SII]6716      6.636      0.66     -56     1
# Comp:  2             [SII]6731      4.981      0.66     -56     1
# Comp:  2              HeII4687     0.1421      0.66     -56     1
# Comp:  2               HeI5876      1.459      0.66     -56     1
# Comp:  2          [OIII]5007_d      10.29      0.83     -56     1
# Comp:  2            [OI]6300_d      3.682      0.83     -56     1
# Comp:  2           [NII]6583_d      5.012      0.83     -56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        70
#  comp.  1:       -51        47
#  comp.  2:       -59        12
# chi2/DOF: 0.6596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.867      0.73     -51    47
# Comp:  1                Halpha      16.73      0.73     -51    47
# Comp:  2             [SII]6716      6.713      0.67     -59    12
# Comp:  2             [SII]6731      4.643      0.67     -59    12
# Comp:  2              HeII4687      0.000      0.67     -59    12
# Comp:  2               HeI5876      1.311      0.67     -59    12
# Comp:  2          [OIII]5007_d      9.553      0.84     -59    12
# Comp:  2            [OI]6300_d      3.769      0.84     -59    12
# Comp:  2           [NII]6583_d      4.903      0.84     -59    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11         1
#  comp.  1:       -46        46
#  comp.  2:       -56        26
# chi2/DOF: 0.6594; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.871      0.73     -46    46
# Comp:  1                Halpha      17.61      0.73     -46    46
# Comp:  2             [SII]6716      6.963      0.68     -56    26
# Comp:  2             [SII]6731      4.937      0.68     -56    26
# Comp:  2              HeII4687      0.000      0.68     -56    26
# Comp:  2               HeI5876     0.9292      0.68     -56    26
# Comp:  2          [OIII]5007_d      10.12      0.86     -56    26
# Comp:  2            [OI]6300_d      3.606      0.86     -56    26
# Comp:  2           [NII]6583_d      5.679      0.86     -56    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        37
#  comp.  1:       -48        42
#  comp.  2:       -58         1
# chi2/DOF: 0.6612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.352      0.72     -48    42
# Comp:  1                Halpha      16.63      0.72     -48    42
# Comp:  2             [SII]6716      6.546      0.66     -58     1
# Comp:  2             [SII]6731      4.642      0.66     -58     1
# Comp:  2              HeII4687    0.04563      0.66     -58     1
# Comp:  2               HeI5876      1.337      0.66     -58     1
# Comp:  2          [OIII]5007_d      10.05      0.83     -58     1
# Comp:  2            [OI]6300_d      3.758      0.83     -58     1
# Comp:  2           [NII]6583_d      4.985      0.83     -58     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -49        45
#  comp.  2:       -54        38
# chi2/DOF: 0.6543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.584      0.73     -49    45
# Comp:  1                Halpha      17.27      0.73     -49    45
# Comp:  2             [SII]6716      7.404      0.71     -54    38
# Comp:  2             [SII]6731      4.703      0.71     -54    38
# Comp:  2              HeII4687    0.07673      0.71     -54    38
# Comp:  2               HeI5876     0.9911      0.71     -54    38
# Comp:  2          [OIII]5007_d      10.79      0.90     -54    38
# Comp:  2            [OI]6300_d      3.608      0.90     -54    38
# Comp:  2           [NII]6583_d      5.817      0.90     -54    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        66
#  comp.  1:       -50        39
#  comp.  2:       -57        12
# chi2/DOF: 0.6578; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.705      0.71     -50    39
# Comp:  1                Halpha      16.26      0.71     -50    39
# Comp:  2             [SII]6716      5.856      0.67     -57    12
# Comp:  2             [SII]6731      4.681      0.67     -57    12
# Comp:  2              HeII4687    0.03501      0.67     -57    12
# Comp:  2               HeI5876      1.686      0.67     -57    12
# Comp:  2          [OIII]5007_d      10.47      0.84     -57    12
# Comp:  2            [OI]6300_d      3.532      0.84     -57    12
# Comp:  2           [NII]6583_d      5.202      0.84     -57    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:       -48        46
#  comp.  2:       -57         1
# chi2/DOF: 0.6580; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.474      0.73     -48    46
# Comp:  1                Halpha      17.08      0.73     -48    46
# Comp:  2             [SII]6716      6.339      0.66     -57     1
# Comp:  2             [SII]6731      4.355      0.66     -57     1
# Comp:  2              HeII4687     0.2579      0.66     -57     1
# Comp:  2               HeI5876      1.219      0.66     -57     1
# Comp:  2          [OIII]5007_d      9.992      0.83     -57     1
# Comp:  2            [OI]6300_d      3.344      0.83     -57     1
# Comp:  2           [NII]6583_d      4.843      0.83     -57     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22        35
#  comp.  1:       -44        42
#  comp.  2:       -59         1
# chi2/DOF: 0.6576; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.936      0.72     -44    42
# Comp:  1                Halpha      17.13      0.72     -44    42
# Comp:  2             [SII]6716      6.587      0.66     -59     1
# Comp:  2             [SII]6731      4.857      0.66     -59     1
# Comp:  2              HeII4687    0.01605      0.66     -59     1
# Comp:  2               HeI5876      1.028      0.66     -59     1
# Comp:  2          [OIII]5007_d      9.333      0.83     -59     1
# Comp:  2            [OI]6300_d      3.833      0.83     -59     1
# Comp:  2           [NII]6583_d      5.092      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        65
#  comp.  1:       -47        47
#  comp.  2:       -55         7
# chi2/DOF: 0.6582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.275      0.73     -47    47
# Comp:  1                Halpha      17.16      0.73     -47    47
# Comp:  2             [SII]6716      5.943      0.66     -55     7
# Comp:  2             [SII]6731      4.530      0.66     -55     7
# Comp:  2              HeII4687      0.000      0.66     -55     7
# Comp:  2               HeI5876      1.190      0.66     -55     7
# Comp:  2          [OIII]5007_d      8.759      0.84     -55     7
# Comp:  2            [OI]6300_d      3.079      0.84     -55     7
# Comp:  2           [NII]6583_d      5.157      0.84     -55     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        93
#  comp.  1:       -48        41
#  comp.  2:       -59         1
# chi2/DOF: 0.6600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.220      0.72     -48    41
# Comp:  1                Halpha      16.88      0.72     -48    41
# Comp:  2             [SII]6716      6.188      0.66     -59     1
# Comp:  2             [SII]6731      4.813      0.66     -59     1
# Comp:  2              HeII4687     0.2230      0.66     -59     1
# Comp:  2               HeI5876      1.085      0.66     -59     1
# Comp:  2          [OIII]5007_d      10.07      0.83     -59     1
# Comp:  2            [OI]6300_d      3.322      0.83     -59     1
# Comp:  2           [NII]6583_d      4.959      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        27
#  comp.  1:       -50        46
#  comp.  2:       -61        27
# chi2/DOF: 0.6595; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.161      0.73     -50    46
# Comp:  1                Halpha      17.14      0.73     -50    46
# Comp:  2             [SII]6716      6.563      0.69     -61    27
# Comp:  2             [SII]6731      5.141      0.69     -61    27
# Comp:  2              HeII4687     0.2330      0.69     -61    27
# Comp:  2               HeI5876      1.388      0.69     -61    27
# Comp:  2          [OIII]5007_d      10.02      0.87     -61    27
# Comp:  2            [OI]6300_d      3.722      0.87     -61    27
# Comp:  2           [NII]6583_d      5.385      0.87     -61    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -51        43
#  comp.  2:       -55         1
# chi2/DOF: 0.6564; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.861      0.72     -51    43
# Comp:  1                Halpha      17.60      0.72     -51    43
# Comp:  2             [SII]6716      6.059      0.66     -55     1
# Comp:  2             [SII]6731      4.839      0.66     -55     1
# Comp:  2              HeII4687      0.000      0.66     -55     1
# Comp:  2               HeI5876      1.228      0.66     -55     1
# Comp:  2          [OIII]5007_d      10.14      0.83     -55     1
# Comp:  2            [OI]6300_d      3.596      0.83     -55     1
# Comp:  2           [NII]6583_d      5.257      0.83     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29       118
#  comp.  1:       -48        49
#  comp.  2:       -54         1
# chi2/DOF: 0.6559; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.63      0.74     -48    49
# Comp:  1                Halpha      17.54      0.74     -48    49
# Comp:  2             [SII]6716      6.109      0.66     -54     1
# Comp:  2             [SII]6731      4.287      0.66     -54     1
# Comp:  2              HeII4687      0.000      0.66     -54     1
# Comp:  2               HeI5876      1.374      0.66     -54     1
# Comp:  2          [OIII]5007_d      10.48      0.83     -54     1
# Comp:  2            [OI]6300_d      3.289      0.83     -54     1
# Comp:  2           [NII]6583_d      4.803      0.83     -54     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        29
#  comp.  1:       -49        38
#  comp.  2:       -54        13
# chi2/DOF: 0.6561; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.026      0.71     -49    38
# Comp:  1                Halpha      17.01      0.71     -49    38
# Comp:  2             [SII]6716      7.061      0.67     -54    13
# Comp:  2             [SII]6731      4.653      0.67     -54    13
# Comp:  2              HeII4687     0.1764      0.67     -54    13
# Comp:  2               HeI5876      1.076      0.67     -54    13
# Comp:  2          [OIII]5007_d      9.987      0.84     -54    13
# Comp:  2            [OI]6300_d      3.177      0.84     -54    13
# Comp:  2           [NII]6583_d      4.913      0.84     -54    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        17
#  comp.  1:       -45        46
#  comp.  2:       -60        24
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.750      0.73     -45    46
# Comp:  1                Halpha      17.13      0.73     -45    46
# Comp:  2             [SII]6716      6.351      0.68     -60    24
# Comp:  2             [SII]6731      4.557      0.68     -60    24
# Comp:  2              HeII4687    0.02681      0.68     -60    24
# Comp:  2               HeI5876      1.564      0.68     -60    24
# Comp:  2          [OIII]5007_d      9.817      0.86     -60    24
# Comp:  2            [OI]6300_d      3.826      0.86     -60    24
# Comp:  2           [NII]6583_d      5.170      0.86     -60    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        65
#  comp.  1:       -49        49
#  comp.  2:       -56        17
# chi2/DOF: 0.6571; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.07      0.74     -49    49
# Comp:  1                Halpha      17.62      0.74     -49    49
# Comp:  2             [SII]6716      7.048      0.67     -56    17
# Comp:  2             [SII]6731      5.043      0.67     -56    17
# Comp:  2              HeII4687     0.3112      0.67     -56    17
# Comp:  2               HeI5876      1.074      0.67     -56    17
# Comp:  2          [OIII]5007_d      10.06      0.85     -56    17
# Comp:  2            [OI]6300_d      3.840      0.85     -56    17
# Comp:  2           [NII]6583_d      5.299      0.85     -56    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:       -50        41
#  comp.  2:       -59         1
# chi2/DOF: 0.6564; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.574      0.72     -50    41
# Comp:  1                Halpha      16.53      0.72     -50    41
# Comp:  2             [SII]6716      6.197      0.66     -59     1
# Comp:  2             [SII]6731      4.260      0.66     -59     1
# Comp:  2              HeII4687     0.3713      0.66     -59     1
# Comp:  2               HeI5876     0.9835      0.66     -59     1
# Comp:  2          [OIII]5007_d      10.11      0.83     -59     1
# Comp:  2            [OI]6300_d      2.957      0.83     -59     1
# Comp:  2           [NII]6583_d      4.866      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -50        40
#  comp.  2:       -53        19
# chi2/DOF: 0.6561; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.322      0.71     -50    40
# Comp:  1                Halpha      16.84      0.71     -50    40
# Comp:  2             [SII]6716      6.511      0.67     -53    19
# Comp:  2             [SII]6731      4.478      0.67     -53    19
# Comp:  2              HeII4687     0.1978      0.67     -53    19
# Comp:  2               HeI5876      1.234      0.67     -53    19
# Comp:  2          [OIII]5007_d      10.38      0.85     -53    19
# Comp:  2            [OI]6300_d      4.020      0.85     -53    19
# Comp:  2           [NII]6583_d      4.898      0.85     -53    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        86
#  comp.  1:       -48        43
#  comp.  2:       -57         1
# chi2/DOF: 0.6575; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.566      0.72     -48    43
# Comp:  1                Halpha      17.31      0.72     -48    43
# Comp:  2             [SII]6716      6.674      0.66     -57     1
# Comp:  2             [SII]6731      4.441      0.66     -57     1
# Comp:  2              HeII4687    0.01595      0.66     -57     1
# Comp:  2               HeI5876      1.280      0.66     -57     1
# Comp:  2          [OIII]5007_d      9.099      0.83     -57     1
# Comp:  2            [OI]6300_d      2.851      0.83     -57     1
# Comp:  2           [NII]6583_d      4.995      0.83     -57     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -50        45
#  comp.  2:       -61        32
# chi2/DOF: 0.6559; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.335      0.73     -50    45
# Comp:  1                Halpha      17.15      0.73     -50    45
# Comp:  2             [SII]6716      6.574      0.70     -61    32
# Comp:  2             [SII]6731      4.677      0.70     -61    32
# Comp:  2              HeII4687    0.09827      0.70     -61    32
# Comp:  2               HeI5876      1.727      0.70     -61    32
# Comp:  2          [OIII]5007_d      10.17      0.88     -61    32
# Comp:  2            [OI]6300_d      3.079      0.88     -61    32
# Comp:  2           [NII]6583_d      4.949      0.88     -61    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -45        47
#  comp.  2:       -51         1
# chi2/DOF: 0.6582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.790      0.73     -45    47
# Comp:  1                Halpha      17.15      0.73     -45    47
# Comp:  2             [SII]6716      6.531      0.66     -51     1
# Comp:  2             [SII]6731      4.380      0.66     -51     1
# Comp:  2              HeII4687     0.2642      0.66     -51     1
# Comp:  2               HeI5876      1.400      0.66     -51     1
# Comp:  2          [OIII]5007_d      8.863      0.83     -51     1
# Comp:  2            [OI]6300_d      3.420      0.83     -51     1
# Comp:  2           [NII]6583_d      5.189      0.83     -51     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:       -48        44
#  comp.  2:       -57         9
# chi2/DOF: 0.6579; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.948      0.72     -48    44
# Comp:  1                Halpha      16.77      0.72     -48    44
# Comp:  2             [SII]6716      5.856      0.66     -57     9
# Comp:  2             [SII]6731      4.685      0.66     -57     9
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.857      0.71     -50    38
# Comp:  1                Halpha      16.07      0.71     -50    38
# Comp:  2             [SII]6716      6.673      0.66     -55     1
# Comp:  2             [SII]6731      4.604      0.66     -55     1
# Comp:  2              HeII4687      0.000      0.66     -55     1
# Comp:  2               HeI5876      1.158      0.66     -55     1
# Comp:  2          [OIII]5007_d      10.15      0.83     -55     1
# Comp:  2            [OI]6300_d      3.488      0.83     -55     1
# Comp:  2           [NII]6583_d      4.869      0.83     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        63
#  comp.  1:       -51        44
#  comp.  2:       -54        13
# chi2/DOF: 0.6566; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.445      0.72     -51    44
# Comp:  1                Halpha      16.79      0.72     -51    44
# Comp:  2             [SII]6716      6.364      0.67     -54    13
# Comp:  2             [SII]6731      4.554      0.67     -54    13
# Comp:  2              HeII4687      0.000      0.67     -54    13
# Comp:  2               HeI5876      1.190      0.67     -54    13
# Comp:  2          [OIII]5007_d      10.39      0.84     -54    13
# Comp:  2            [OI]6300_d      3.673      0.84     -54    13
# Comp:  2           [NII]6583_d      5.117      0.84     -54    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         1
#  comp.  1:       -49        39
#  comp.  2:       -56         1
# chi2/DOF: 0.6586; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.346      0.71     -49    39
# Comp:  1                Halpha      16.61      0.71     -49    39
# Comp:  2             [SII]6716      6.417      0.66     -56     1
# Comp:  2             [SII]6731      4.724      0.66     -56     1
# Comp:  2              HeII4687      0.000      0.66     -56     1
# Comp:  2               HeI5876      1.536      0.66     -56     1
# Comp:  2          [OIII]5007_d      9.839      0.83     -56     1
# Comp:  2            [OI]6300_d      3.342      0.83     -56     1
# Comp:  2           [NII]6583_d      5.372      0.83     -56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37       101
#  comp.  1:       -52        42
#  comp.  2:       -65         1
# chi2/DOF: 0.6567; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.602      0.72     -52    42
# Comp:  1                Halpha      16.68      0.72     -52    42
# Comp:  2             [SII]6716      6.180      0.66     -65     1
# Comp:  2             [SII]6731      4.807      0.66     -65     1
# Comp:  2              HeII4687     0.2705      0.66     -65     1
# Comp:  2               HeI5876      1.183      0.66     -65     1
# Comp:  2          [OIII]5007_d      8.354      0.83     -65     1
# Comp:  2            [OI]6300_d      3.787      0.83     -65     1
# Comp:  2           [NII]6583_d      4.982      0.83     -65     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -46        39
#  comp.  2:       -61         8
# chi2/DOF: 0.6564; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.437      0.71     -46    39
# Comp:  1                Halpha      16.82      0.71     -46    39
# Comp:  2             [SII]6716      6.854      0.66     -61     8
# Comp:  2             [SII]6731      4.799      0.66     -61     8
# Comp:  2              HeII4687      0.000      0.66     -61     8
# Comp:  2               HeI5876     0.7997      0.66     -61     8
# Comp:  2          [OIII]5007_d      9.328      0.84     -61     8
# Comp:  2            [OI]6300_d      3.575      0.84     -61     8
# Comp:  2           [NII]6583_d      4.992      0.84     -61     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        43
#  comp.  1:       -49        48
#  comp.  2:       -60         1
# chi2/DOF: 0.6576; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.41      0.74     -49    48
# Comp:  1                Halpha      17.37      0.74     -49    48
# Comp:  2             [SII]6716      6.698      0.66     -60     1
# Comp:  2             [SII]6731      4.813      0.66     -60     1
# Comp:  2              HeII4687    0.09348      0.66     -60     1
# Comp:  2               HeI5876      1.321      0.66     -60     1
# Comp:  2          [OIII]5007_d      8.747      0.83     -60     1
# Comp:  2            [OI]6300_d      3.386      0.83     -60     1
# Comp:  2           [NII]6583_d      5.223      0.83     -60     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -49        45
#  comp.  2:       -51        22
# chi2/DOF: 0.6577; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.259      0.73     -49    45
# Comp:  1                Halpha      17.05      0.73     -49    45
# Comp:  2             [SII]6716      6.045      0.68     -51    22
# Comp:  2             [SII]6731      4.975      0.68     -51    22
# Comp:  2              HeII4687     0.2174      0.68     -51    22
# Comp:  2               HeI5876      1.520      0.68     -51    22
# Comp:  2          [OIII]5007_d      9.751      0.86     -51    22
# Comp:  2            [OI]6300_d      3.960      0.86     -51    22
# Comp:  2           [NII]6583_d      5.532      0.86     -51    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13        57
#  comp.  1:       -46        48
#  comp.  2:       -63        22
# chi2/DOF: 0.6569; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.962      0.74     -46    48
# Comp:  1                Halpha      17.49      0.74     -46    48
# Comp:  2             [SII]6716      6.872      0.68     -63    22
# Comp:  2             [SII]6731      4.682      0.68     -63    22
# Comp:  2              HeII4687     0.1110      0.68     -63    22
# Comp:  2               HeI5876      1.489      0.68     -63    22
# Comp:  2          [OIII]5007_d      9.096      0.86     -63    22
# Comp:  2            [OI]6300_d      2.837      0.86     -63    22
# Comp:  2           [NII]6583_d      5.090      0.86     -63    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        52
#  comp.  1:       -50        44
#  comp.  2:       -59        35
# chi2/DOF: 0.6580; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.700      0.72     -50    44
# Comp:  1                Halpha      17.02      0.72     -50    44
# Comp:  2             [SII]6716      6.868      0.70     -59    35
# Comp:  2             [SII]6731      5.059      0.70     -59    35
# Comp:  2              HeII4687    0.05892      0.70     -59    35
# Comp:  2               HeI5876      1.217      0.70     -59    35
# Comp:  2          [OIII]5007_d      9.597      0.89     -59    35
# Comp:  2            [OI]6300_d      3.630      0.89     -59    35
# Comp:  2           [NII]6583_d      5.501      0.89     -59    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        46
#  comp.  1:       -49        44
#  comp.  2:       -58        15
# chi2/DOF: 0.6609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.626      0.72     -49    44
# Comp:  1                Halpha      16.93      0.72     -49    44
# Comp:  2             [SII]6716      6.519      0.67     -58    15
# Comp:  2             [SII]6731      4.879      0.67     -58    15
# Comp:  2              HeII4687      0.000      0.67     -58    15
# Comp:  2               HeI5876      1.083      0.67     -58    15
# Comp:  2          [OIII]5007_d      9.167      0.85     -58    15
# Comp:  2            [OI]6300_d      3.181      0.85     -58    15
# Comp:  2           [NII]6583_d      5.318      0.85     -58    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        44
#  comp.  1:       -51        47
#  comp.  2:       -59         1
# chi2/DOF: 0.6597; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.833      0.73     -51    47
# Comp:  1                Halpha      17.21      0.73     -51    47
# Comp:  2             [SII]6716      6.346      0.66     -59     1
# Comp:  2             [SII]6731      4.876      0.66     -59     1
# Comp:  2              HeII4687    0.02445      0.66     -59     1
# Comp:  2               HeI5876     0.9289      0.66     -59     1
# Comp:  2          [OIII]5007_d      9.467      0.83     -59     1
# Comp:  2            [OI]6300_d      3.124      0.83     -59     1
# Comp:  2           [NII]6583_d      5.341      0.83     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        78
#  comp.  1:       -52        44
#  comp.  2:       -56         1
# chi2/DOF: 0.6592; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.336      0.72     -52    44
# Comp:  1                Halpha      17.22      0.72     -52    44
# Comp:  2             [SII]6716      6.563      0.66     -56     1
# Comp:  2             [SII]6731      4.407      0.66     -56     1
# Comp:  2              HeII4687    0.07697      0.66     -56     1
# Comp:  2               HeI5876      1.031      0.66     -56     1
# Comp:  2          [OIII]5007_d      9.590      0.83     -56     1
# Comp:  2            [OI]6300_d      3.407      0.83     -56     1
# Comp:  2           [NII]6583_d      4.976      0.83     -56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        34
#  comp.  1:       -51        47
#  comp.  2:       -59        18
# chi2/DOF: 0.6545; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.731      0.73     -51    47
# Comp:  1                Halpha      17.24      0.73     -51    47
# Comp:  2             [SII]6716      5.995      0.67     -59    18
# Comp:  2             [SII]6731      4.359      0.67     -59    18
# Comp:  2              HeII4687      0.000      0.67     -59    18
# Comp:  2               HeI5876     0.8261      0.67     -59    18
# Comp:  2          [OIII]5007_d      8.860      0.85     -59    18
# Comp:  2            [OI]6300_d      3.886      0.85     -59    18
# Comp:  2           [NII]6583_d      4.942      0.85     -59    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        20
#  comp.  1:       -49        50
#  comp.  2:       -59        30
# chi2/DOF: 0.6564; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.31      0.74     -49    50
# Comp:  1                Halpha      17.52      0.74     -49    50
# Comp:  2             [SII]6716      7.297      0.69     -59    30
# Comp:  2             [SII]6731      5.137      0.69     -59    30
# Comp:  2              HeII4687     0.4780      0.69     -59    30
# Comp:  2               HeI5876      1.476      0.69     -59    30
# Comp:  2          [OIII]5007_d      9.508      0.88     -59    30
# Comp:  2            [OI]6300_d      3.652      0.88     -59    30
# Comp:  2           [NII]6583_d      5.557      0.88     -59    30
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.7943024 , 0.49639009, 0.5270635 , 0.33818866, 0.11205021,
#        0.2836915 , 0.60352432, 0.46789853, 0.29584693])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 9.06026874, 23.12346208,  8.92534894,  6.45621612,  0.02431706,
#         1.49306839,  9.90179621,  4.44950395,  6.95403543])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_20_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_20", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_20_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_20_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_20_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.135310    0.011862
# 1        Halpha  0.345335    0.007413
# 2     [SII]6716  0.133295    0.007871
# 3     [SII]6731  0.096420    0.005051
# 4      HeII4687  0.000363    0.001673
# 5       HeI5876  0.022298    0.004237
# 6  [OIII]5007_d  0.147877    0.009013
# 7    [OI]6300_d  0.066451    0.006988
# 8   [NII]6583_d  0.103854    0.004418
#           Name      Flux  Error_flux
# 0        Hbeta  0.135310    0.011862
# 1       Halpha  0.345335    0.007413
# 2    [SII]6716  0.133295    0.007871
# 3    [SII]6731  0.096420    0.005051
# 4     HeII4687  0.000363    0.001673
# 5      HeI5876  0.022298    0.004237
# 6   [OIII]4959  0.036969    0.009013
# 7   [OIII]5007  0.110908    0.009013
# 8     [OI]6300  0.049838    0.006988
# 9     [OI]6364  0.016613    0.006988
# 10   [NII]6548  0.025964    0.004418
# 11   [NII]6583  0.077891    0.004418

# %%
np.median(flux_rf_rebin)
# Out:
# 0.014934403908259015
