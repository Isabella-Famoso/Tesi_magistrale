# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_6.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188  
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_6']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.06638042 0.06053504 0.05952505 ... 0.05046719 0.04857818 0.04975367] [0.005094 0.005094 0.005094 ... 0.005094 0.005094 0.005094]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        23
# chi2/DOF: 0.01080; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -98         1
# chi2/DOF: 0.005879; DOF: 1897; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-97.79502182,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -506      1000
#  comp.  1:       -82        23
#  comp.  2:       -84        24
# chi2/DOF: 2.946; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.10      0.18     -82    23
# Comp:  1                Halpha      230.7      0.18     -82    23
# Comp:  2             [SII]6716      29.40      0.18     -84    24
# Comp:  2             [SII]6731      19.70      0.18     -84    24
# Comp:  2              HeII4687     0.1570      0.18     -84    24
# Comp:  2               HeI5876      7.632      0.18     -84    24
# Comp:  2          [OIII]5007_d      53.62      0.22     -84    24
# Comp:  2            [OI]6300_d      3.215      0.22     -84    24
# Comp:  2           [NII]6583_d      62.30      0.22     -84    24
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  162.7; gas flux:     42 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  941.1; gas flux:    316 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  120.5; gas flux:     41 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   77.9; gas flux:     28 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.6397; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  30.89; gas flux:      9 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  159.1; gas flux:     56 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  9.317; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  189.9; gas flux:     86 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -440       605
#  comp.  1:       -83        27
#  comp.  2:       -83        21
# chi2/DOF: 2.690; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.25      0.18     -83    27
# Comp:  1                Halpha      232.4      0.18     -83    27
# Comp:  2             [SII]6716      29.17      0.18     -83    21
# Comp:  2             [SII]6731      20.09      0.18     -83    21
# Comp:  2              HeII4687     0.2100      0.18     -83    21
# Comp:  2               HeI5876      7.556      0.18     -83    21
# Comp:  2          [OIII]5007_d      53.49      0.22     -83    21
# Comp:  2            [OI]6300_d      2.646      0.22     -83    21
# Comp:  2           [NII]6583_d      61.45      0.22     -83    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -201       814
#  comp.  1:       -81        25
#  comp.  2:       -84        23
# chi2/DOF: 2.670; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.93      0.18     -81    25
# Comp:  1                Halpha      229.5      0.18     -81    25
# Comp:  2             [SII]6716      29.79      0.18     -84    23
# Comp:  2             [SII]6731      19.35      0.18     -84    23
# Comp:  2              HeII4687     0.1076      0.18     -84    23
# Comp:  2               HeI5876      7.438      0.18     -84    23
# Comp:  2          [OIII]5007_d      55.20      0.22     -84    23
# Comp:  2            [OI]6300_d      3.427      0.22     -84    23
# Comp:  2           [NII]6583_d      61.01      0.22     -84    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -247       862
#  comp.  1:       -83        23
#  comp.  2:       -83        23
# chi2/DOF: 2.861; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.75      0.18     -83    23
# Comp:  1                Halpha      230.9      0.18     -83    23
# Comp:  2             [SII]6716      28.56      0.18     -83    23
# Comp:  2             [SII]6731      20.28      0.18     -83    23
# Comp:  2              HeII4687     0.2336      0.18     -83    23
# Comp:  2               HeI5876      7.338      0.18     -83    23
# Comp:  2          [OIII]5007_d      52.28      0.22     -83    23
# Comp:  2            [OI]6300_d      3.165      0.22     -83    23
# Comp:  2           [NII]6583_d      61.05      0.22     -83    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -600      1000
#  comp.  1:       -81        21
#  comp.  2:       -83        14
# chi2/DOF: 2.360; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.03      0.18     -81    21
# Comp:  1                Halpha      227.7      0.18     -81    21
# Comp:  2             [SII]6716      28.95      0.17     -83    14
# Comp:  2             [SII]6731      19.22      0.17     -83    14
# Comp:  2              HeII4687    0.07213      0.17     -83    14
# Comp:  2               HeI5876      7.336      0.17     -83    14
# Comp:  2          [OIII]5007_d      52.07      0.22     -83    14
# Comp:  2            [OI]6300_d      2.737      0.22     -83    14
# Comp:  2           [NII]6583_d      60.37      0.22     -83    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:       -82        24
#  comp.  2:       -84        21
# chi2/DOF: 2.695; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.44      0.18     -82    24
# Comp:  1                Halpha      229.5      0.18     -82    24
# Comp:  2             [SII]6716      29.80      0.18     -84    21
# Comp:  2             [SII]6731      18.98      0.18     -84    21
# Comp:  2              HeII4687     0.1158      0.18     -84    21
# Comp:  2               HeI5876      7.299      0.18     -84    21
# Comp:  2          [OIII]5007_d      54.21      0.22     -84    21
# Comp:  2            [OI]6300_d      3.367      0.22     -84    21
# Comp:  2           [NII]6583_d      62.24      0.22     -84    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -214       877
#  comp.  1:       -82        18
#  comp.  2:       -83        26
# chi2/DOF: 2.651; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.83      0.17     -82    18
# Comp:  1                Halpha      228.6      0.17     -82    18
# Comp:  2             [SII]6716      28.97      0.18     -83    26
# Comp:  2             [SII]6731      20.12      0.18     -83    26
# Comp:  2              HeII4687     0.1046      0.18     -83    26
# Comp:  2               HeI5876      7.729      0.18     -83    26
# Comp:  2          [OIII]5007_d      53.10      0.22     -83    26
# Comp:  2            [OI]6300_d      3.284      0.22     -83    26
# Comp:  2           [NII]6583_d      64.13      0.22     -83    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -828       973
#  comp.  1:       -81        21
#  comp.  2:       -87        28
# chi2/DOF: 2.660; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.96      0.18     -81    21
# Comp:  1                Halpha      227.9      0.18     -81    21
# Comp:  2             [SII]6716      29.57      0.18     -87    28
# Comp:  2             [SII]6731      20.20      0.18     -87    28
# Comp:  2              HeII4687    0.03908      0.18     -87    28
# Comp:  2               HeI5876      7.991      0.18     -87    28
# Comp:  2          [OIII]5007_d      54.08      0.23     -87    28
# Comp:  2            [OI]6300_d      3.400      0.23     -87    28
# Comp:  2           [NII]6583_d      61.64      0.23     -87    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -253       649
#  comp.  1:       -82        24
#  comp.  2:       -84        29
# chi2/DOF: 2.220; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.92      0.18     -82    24
# Comp:  1                Halpha      229.1      0.18     -82    24
# Comp:  2             [SII]6716      29.46      0.18     -84    29
# Comp:  2             [SII]6731      19.74      0.18     -84    29
# Comp:  2              HeII4687     0.1958      0.18     -84    29
# Comp:  2               HeI5876      7.220      0.18     -84    29
# Comp:  2          [OIII]5007_d      54.59      0.23     -84    29
# Comp:  2            [OI]6300_d      3.756      0.23     -84    29
# Comp:  2           [NII]6583_d      62.12      0.23     -84    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -391       897
#  comp.  1:       -81        21
#  comp.  2:       -82        26
# chi2/DOF: 2.361; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.98      0.18     -81    21
# Comp:  1                Halpha      227.5      0.18     -81    21
# Comp:  2             [SII]6716      29.87      0.18     -82    26
# Comp:  2             [SII]6731      19.75      0.18     -82    26
# Comp:  2              HeII4687     0.1415      0.18     -82    26
# Comp:  2               HeI5876      7.476      0.18     -82    26
# Comp:  2          [OIII]5007_d      52.42      0.22     -82    26
# Comp:  2            [OI]6300_d      3.342      0.22     -82    26
# Comp:  2           [NII]6583_d      61.98      0.22     -82    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -716      1000
#  comp.  1:       -82        25
#  comp.  2:       -85        22
# chi2/DOF: 2.830; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.78      0.18     -82    25
# Comp:  1                Halpha      230.7      0.18     -82    25
# Comp:  2             [SII]6716      29.41      0.18     -85    22
# Comp:  2             [SII]6731      19.31      0.18     -85    22
# Comp:  2              HeII4687     0.1145      0.18     -85    22
# Comp:  2               HeI5876      7.667      0.18     -85    22
# Comp:  2          [OIII]5007_d      54.76      0.22     -85    22
# Comp:  2            [OI]6300_d      3.215      0.22     -85    22
# Comp:  2           [NII]6583_d      60.89      0.22     -85    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -247      1000
#  comp.  1:       -83        22
#  comp.  2:       -83        16
# chi2/DOF: 2.386; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.91      0.18     -83    22
# Comp:  1                Halpha      231.5      0.18     -83    22
# Comp:  2             [SII]6716      28.91      0.17     -83    16
# Comp:  2             [SII]6731      18.96      0.17     -83    16
# Comp:  2              HeII4687     0.1488      0.17     -83    16
# Comp:  2               HeI5876      7.960      0.17     -83    16
# Comp:  2          [OIII]5007_d      50.40      0.22     -83    16
# Comp:  2            [OI]6300_d      3.411      0.22     -83    16
# Comp:  2           [NII]6583_d      62.68      0.22     -83    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -774      1000
#  comp.  1:       -83        25
#  comp.  2:       -86        24
# chi2/DOF: 2.321; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.33      0.18     -83    25
# Comp:  1                Halpha      233.7      0.18     -83    25
# Comp:  2             [SII]6716      28.97      0.18     -86    24
# Comp:  2             [SII]6731      19.93      0.18     -86    24
# Comp:  2              HeII4687     0.1389      0.18     -86    24
# Comp:  2               HeI5876      7.986      0.18     -86    24
# Comp:  2          [OIII]5007_d      53.63      0.22     -86    24
# Comp:  2            [OI]6300_d      3.087      0.22     -86    24
# Comp:  2           [NII]6583_d      61.91      0.22     -86    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       757
#  comp.  1:       -83        24
#  comp.  2:       -86        25
# chi2/DOF: 2.465; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.01      0.18     -83    24
# Comp:  1                Halpha      231.0      0.18     -83    24
# Comp:  2             [SII]6716      30.28      0.18     -86    25
# Comp:  2             [SII]6731      20.25      0.18     -86    25
# Comp:  2              HeII4687     0.2015      0.18     -86    25
# Comp:  2               HeI5876      7.447      0.18     -86    25
# Comp:  2          [OIII]5007_d      53.62      0.22     -86    25
# Comp:  2            [OI]6300_d      2.992      0.22     -86    25
# Comp:  2           [NII]6583_d      62.22      0.22     -86    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -142       750
#  comp.  1:       -82        24
#  comp.  2:       -85        26
# chi2/DOF: 2.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.44      0.18     -82    24
# Comp:  1                Halpha      228.9      0.18     -82    24
# Comp:  2             [SII]6716      30.38      0.18     -85    26
# Comp:  2             [SII]6731      20.30      0.18     -85    26
# Comp:  2              HeII4687     0.1616      0.18     -85    26
# Comp:  2               HeI5876      7.954      0.18     -85    26
# Comp:  2          [OIII]5007_d      52.69      0.22     -85    26
# Comp:  2            [OI]6300_d      3.151      0.22     -85    26
# Comp:  2           [NII]6583_d      62.17      0.22     -85    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -411      1000
#  comp.  1:       -81        19
#  comp.  2:       -85        25
# chi2/DOF: 2.058; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.58      0.18     -81    19
# Comp:  1                Halpha      229.6      0.18     -81    19
# Comp:  2             [SII]6716      30.08      0.18     -85    25
# Comp:  2             [SII]6731      19.02      0.18     -85    25
# Comp:  2              HeII4687      0.000      0.18     -85    25
# Comp:  2               HeI5876      8.190      0.18     -85    25
# Comp:  2          [OIII]5007_d      54.19      0.22     -85    25
# Comp:  2            [OI]6300_d      3.217      0.22     -85    25
# Comp:  2           [NII]6583_d      62.71      0.22     -85    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -908      1000
#  comp.  1:       -82        21
#  comp.  2:       -85        34
# chi2/DOF: 2.279; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.98      0.18     -82    21
# Comp:  1                Halpha      229.3      0.18     -82    21
# Comp:  2             [SII]6716      30.12      0.18     -85    34
# Comp:  2             [SII]6731      20.29      0.18     -85    34
# Comp:  2              HeII4687     0.2446      0.18     -85    34
# Comp:  2               HeI5876      7.393      0.18     -85    34
# Comp:  2          [OIII]5007_d      56.92      0.23     -85    34
# Comp:  2            [OI]6300_d      3.238      0.23     -85    34
# Comp:  2           [NII]6583_d      63.72      0.23     -85    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -493      1000
#  comp.  1:       -82        22
#  comp.  2:       -83        11
# chi2/DOF: 2.229; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.79      0.18     -82    22
# Comp:  1                Halpha      231.1      0.18     -82    22
# Comp:  2             [SII]6716      29.23      0.17     -83    11
# Comp:  2             [SII]6731      19.00      0.17     -83    11
# Comp:  2              HeII4687     0.1052      0.17     -83    11
# Comp:  2               HeI5876      7.077      0.17     -83    11
# Comp:  2          [OIII]5007_d      50.35      0.22     -83    11
# Comp:  2            [OI]6300_d      3.010      0.22     -83    11
# Comp:  2           [NII]6583_d      62.20      0.22     -83    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -882      1000
#  comp.  1:       -82        26
#  comp.  2:       -83        28
# chi2/DOF: 2.277; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.08      0.18     -82    26
# Comp:  1                Halpha      232.7      0.18     -82    26
# Comp:  2             [SII]6716      30.00      0.18     -83    28
# Comp:  2             [SII]6731      19.05      0.18     -83    28
# Comp:  2              HeII4687     0.1007      0.18     -83    28
# Comp:  2               HeI5876      7.803      0.18     -83    28
# Comp:  2          [OIII]5007_d      55.45      0.23     -83    28
# Comp:  2            [OI]6300_d      2.863      0.23     -83    28
# Comp:  2           [NII]6583_d      63.00      0.23     -83    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -780      1000
#  comp.  1:       -83        24
#  comp.  2:       -81        16
# chi2/DOF: 2.183; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.92      0.18     -83    24
# Comp:  1                Halpha      230.7      0.18     -83    24
# Comp:  2             [SII]6716      29.69      0.17     -81    16
# Comp:  2             [SII]6731      19.26      0.17     -81    16
# Comp:  2              HeII4687     0.1404      0.17     -81    16
# Comp:  2               HeI5876      7.307      0.17     -81    16
# Comp:  2          [OIII]5007_d      51.80      0.22     -81    16
# Comp:  2            [OI]6300_d      3.766      0.22     -81    16
# Comp:  2           [NII]6583_d      60.31      0.22     -81    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -604      1000
#  comp.  1:       -83        26
#  comp.  2:       -86        31
# chi2/DOF: 2.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.08      0.18     -83    26
# Comp:  1                Halpha      232.2      0.18     -83    26
# Comp:  2             [SII]6716      29.26      0.18     -86    31
# Comp:  2             [SII]6731      20.86      0.18     -86    31
# Comp:  2              HeII4687      0.000      0.18     -86    31
# Comp:  2               HeI5876      7.187      0.18     -86    31
# Comp:  2          [OIII]5007_d      55.67      0.23     -86    31
# Comp:  2            [OI]6300_d      3.471      0.23     -86    31
# Comp:  2           [NII]6583_d      63.18      0.23     -86    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3       112
#  comp.  1:       -82        23
#  comp.  2:       -86        34
# chi2/DOF: 2.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.06      0.18     -82    23
# Comp:  1                Halpha      228.7      0.18     -82    23
# Comp:  2             [SII]6716      29.90      0.18     -86    34
# Comp:  2             [SII]6731      20.91      0.18     -86    34
# Comp:  2              HeII4687     0.1379      0.18     -86    34
# Comp:  2               HeI5876      8.117      0.18     -86    34
# Comp:  2          [OIII]5007_d      56.51      0.23     -86    34
# Comp:  2            [OI]6300_d      3.820      0.23     -86    34
# Comp:  2           [NII]6583_d      63.51      0.23     -86    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -467      1000
#  comp.  1:       -82        24
#  comp.  2:       -85        24
# chi2/DOF: 2.818; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.59      0.18     -82    24
# Comp:  1                Halpha      229.9      0.18     -82    24
# Comp:  2             [SII]6716      29.81      0.18     -85    24
# Comp:  2             [SII]6731      19.36      0.18     -85    24
# Comp:  2              HeII4687    0.08925      0.18     -85    24
# Comp:  2               HeI5876      7.956      0.18     -85    24
# Comp:  2          [OIII]5007_d      55.35      0.22     -85    24
# Comp:  2            [OI]6300_d      3.315      0.22     -85    24
# Comp:  2           [NII]6583_d      61.74      0.22     -85    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -805       321
#  comp.  1:       -83        22
#  comp.  2:       -85        30
# chi2/DOF: 2.737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.12      0.18     -83    22
# Comp:  1                Halpha      231.4      0.18     -83    22
# Comp:  2             [SII]6716      30.20      0.18     -85    30
# Comp:  2             [SII]6731      20.24      0.18     -85    30
# Comp:  2              HeII4687      0.000      0.18     -85    30
# Comp:  2               HeI5876      7.530      0.18     -85    30
# Comp:  2          [OIII]5007_d      56.71      0.23     -85    30
# Comp:  2            [OI]6300_d      3.304      0.23     -85    30
# Comp:  2           [NII]6583_d      63.63      0.23     -85    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -371       741
#  comp.  1:       -83        23
#  comp.  2:       -86        31
# chi2/DOF: 2.622; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.23      0.18     -83    23
# Comp:  1                Halpha      233.5      0.18     -83    23
# Comp:  2             [SII]6716      30.25      0.18     -86    31
# Comp:  2             [SII]6731      20.56      0.18     -86    31
# Comp:  2              HeII4687     0.1843      0.18     -86    31
# Comp:  2               HeI5876      8.093      0.18     -86    31
# Comp:  2          [OIII]5007_d      55.61      0.23     -86    31
# Comp:  2            [OI]6300_d      3.529      0.23     -86    31
# Comp:  2           [NII]6583_d      62.37      0.23     -86    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -452      1000
#  comp.  1:       -82        25
#  comp.  2:       -86        33
# chi2/DOF: 2.653; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.69      0.18     -82    25
# Comp:  1                Halpha      230.1      0.18     -82    25
# Comp:  2             [SII]6716      31.18      0.18     -86    33
# Comp:  2             [SII]6731      20.26      0.18     -86    33
# Comp:  2              HeII4687     0.2963      0.18     -86    33
# Comp:  2               HeI5876      7.874      0.18     -86    33
# Comp:  2          [OIII]5007_d      57.67      0.23     -86    33
# Comp:  2            [OI]6300_d      2.919      0.23     -86    33
# Comp:  2           [NII]6583_d      64.77      0.23     -86    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -237       936
#  comp.  1:       -82        19
#  comp.  2:       -85        30
# chi2/DOF: 2.670; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.34      0.17     -82    19
# Comp:  1                Halpha      228.3      0.17     -82    19
# Comp:  2             [SII]6716      29.20      0.18     -85    30
# Comp:  2             [SII]6731      20.37      0.18     -85    30
# Comp:  2              HeII4687    0.09873      0.18     -85    30
# Comp:  2               HeI5876      8.234      0.18     -85    30
# Comp:  2          [OIII]5007_d      55.83      0.23     -85    30
# Comp:  2            [OI]6300_d      3.217      0.23     -85    30
# Comp:  2           [NII]6583_d      62.20      0.23     -85    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -190       811
#  comp.  1:       -84        24
#  comp.  2:       -85        25
# chi2/DOF: 2.626; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.94      0.18     -84    24
# Comp:  1                Halpha      233.2      0.18     -84    24
# Comp:  2             [SII]6716      29.60      0.18     -85    25
# Comp:  2             [SII]6731      19.00      0.18     -85    25
# Comp:  2              HeII4687     0.2054      0.18     -85    25
# Comp:  2               HeI5876      7.487      0.18     -85    25
# Comp:  2          [OIII]5007_d      54.54      0.22     -85    25
# Comp:  2            [OI]6300_d      3.315      0.22     -85    25
# Comp:  2           [NII]6583_d      62.17      0.22     -85    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -647       988
#  comp.  1:       -83        21
#  comp.  2:       -86        29
# chi2/DOF: 2.421; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.43      0.18     -83    21
# Comp:  1                Halpha      231.8      0.18     -83    21
# Comp:  2             [SII]6716      29.39      0.18     -86    29
# Comp:  2             [SII]6731      20.40      0.18     -86    29
# Comp:  2              HeII4687     0.1528      0.18     -86    29
# Comp:  2               HeI5876      7.959      0.18     -86    29
# Comp:  2          [OIII]5007_d      53.63      0.23     -86    29
# Comp:  2            [OI]6300_d      3.493      0.23     -86    29
# Comp:  2           [NII]6583_d      63.98      0.23     -86    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -872      1000
#  comp.  1:       -83        23
#  comp.  2:       -82        19
# chi2/DOF: 2.152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.83      0.18     -83    23
# Comp:  1                Halpha      232.3      0.18     -83    23
# Comp:  2             [SII]6716      28.62      0.18     -82    19
# Comp:  2             [SII]6731      20.04      0.18     -82    19
# Comp:  2              HeII4687   0.004460      0.18     -82    19
# Comp:  2               HeI5876      7.355      0.18     -82    19
# Comp:  2          [OIII]5007_d      52.35      0.22     -82    19
# Comp:  2            [OI]6300_d      3.344      0.22     -82    19
# Comp:  2           [NII]6583_d      63.16      0.22     -82    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        95
#  comp.  1:       -81        21
#  comp.  2:       -84        19
# chi2/DOF: 2.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.54      0.18     -81    21
# Comp:  1                Halpha      228.9      0.18     -81    21
# Comp:  2             [SII]6716      29.51      0.17     -84    19
# Comp:  2             [SII]6731      19.85      0.17     -84    19
# Comp:  2              HeII4687     0.2141      0.17     -84    19
# Comp:  2               HeI5876      7.111      0.17     -84    19
# Comp:  2          [OIII]5007_d      52.12      0.22     -84    19
# Comp:  2            [OI]6300_d      3.171      0.22     -84    19
# Comp:  2           [NII]6583_d      63.26      0.22     -84    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -455      1000
#  comp.  1:       -81        25
#  comp.  2:       -86        31
# chi2/DOF: 2.735; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.36      0.18     -81    25
# Comp:  1                Halpha      230.0      0.18     -81    25
# Comp:  2             [SII]6716      30.39      0.18     -86    31
# Comp:  2             [SII]6731      20.57      0.18     -86    31
# Comp:  2              HeII4687    0.09300      0.18     -86    31
# Comp:  2               HeI5876      7.402      0.18     -86    31
# Comp:  2          [OIII]5007_d      54.72      0.23     -86    31
# Comp:  2            [OI]6300_d      3.002      0.23     -86    31
# Comp:  2           [NII]6583_d      63.55      0.23     -86    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       995
#  comp.  1:       -82        23
#  comp.  2:       -80        23
# chi2/DOF: 2.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.42      0.18     -82    23
# Comp:  1                Halpha      229.2      0.18     -82    23
# Comp:  2             [SII]6716      29.47      0.18     -80    23
# Comp:  2             [SII]6731      19.89      0.18     -80    23
# Comp:  2              HeII4687    0.02536      0.18     -80    23
# Comp:  2               HeI5876      7.391      0.18     -80    23
# Comp:  2          [OIII]5007_d      53.23      0.22     -80    23
# Comp:  2            [OI]6300_d      3.008      0.22     -80    23
# Comp:  2           [NII]6583_d      61.60      0.22     -80    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -248      1000
#  comp.  1:       -81        19
#  comp.  2:       -82        20
# chi2/DOF: 2.316; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.24      0.18     -81    19
# Comp:  1                Halpha      225.7      0.18     -81    19
# Comp:  2             [SII]6716      29.46      0.18     -82    20
# Comp:  2             [SII]6731      18.73      0.18     -82    20
# Comp:  2              HeII4687    0.04933      0.18     -82    20
# Comp:  2               HeI5876      7.935      0.18     -82    20
# Comp:  2          [OIII]5007_d      53.08      0.22     -82    20
# Comp:  2            [OI]6300_d      3.053      0.22     -82    20
# Comp:  2           [NII]6583_d      62.13      0.22     -82    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1341      1000
#  comp.  1:       -81        21
#  comp.  2:       -82        19
# chi2/DOF: 2.614; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.25      0.18     -81    21
# Comp:  1                Halpha      229.8      0.18     -81    21
# Comp:  2             [SII]6716      29.96      0.17     -82    19
# Comp:  2             [SII]6731      19.47      0.17     -82    19
# Comp:  2              HeII4687     0.1821      0.17     -82    19
# Comp:  2               HeI5876      7.087      0.17     -82    19
# Comp:  2          [OIII]5007_d      53.37      0.22     -82    19
# Comp:  2            [OI]6300_d      2.847      0.22     -82    19
# Comp:  2           [NII]6583_d      59.74      0.22     -82    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -235         1
#  comp.  1:       -82        23
#  comp.  2:       -86        22
# chi2/DOF: 2.863; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.67      0.18     -82    23
# Comp:  1                Halpha      231.5      0.18     -82    23
# Comp:  2             [SII]6716      29.64      0.18     -86    22
# Comp:  2             [SII]6731      19.12      0.18     -86    22
# Comp:  2              HeII4687     0.1111      0.18     -86    22
# Comp:  2               HeI5876      7.760      0.18     -86    22
# Comp:  2          [OIII]5007_d      54.25      0.22     -86    22
# Comp:  2            [OI]6300_d      3.199      0.22     -86    22
# Comp:  2           [NII]6583_d      61.53      0.22     -86    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1178      1000
#  comp.  1:       -81        24
#  comp.  2:       -84        25
# chi2/DOF: 2.791; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.82      0.18     -81    24
# Comp:  1                Halpha      232.4      0.18     -81    24
# Comp:  2             [SII]6716      30.43      0.18     -84    25
# Comp:  2             [SII]6731      20.55      0.18     -84    25
# Comp:  2              HeII4687     0.2574      0.18     -84    25
# Comp:  2               HeI5876      7.999      0.18     -84    25
# Comp:  2          [OIII]5007_d      53.04      0.22     -84    25
# Comp:  2            [OI]6300_d      3.738      0.22     -84    25
# Comp:  2           [NII]6583_d      63.38      0.22     -84    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        73
#  comp.  1:       -83        23
#  comp.  2:       -82        18
# chi2/DOF: 2.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.77      0.18     -83    23
# Comp:  1                Halpha      233.2      0.18     -83    23
# Comp:  2             [SII]6716      28.55      0.17     -82    18
# Comp:  2             [SII]6731      19.28      0.17     -82    18
# Comp:  2              HeII4687     0.1893      0.17     -82    18
# Comp:  2               HeI5876      7.575      0.17     -82    18
# Comp:  2          [OIII]5007_d      52.21      0.22     -82    18
# Comp:  2            [OI]6300_d      3.162      0.22     -82    18
# Comp:  2           [NII]6583_d      62.36      0.22     -82    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -537      1000
#  comp.  1:       -82        24
#  comp.  2:       -85        28
# chi2/DOF: 2.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.38      0.18     -82    24
# Comp:  1                Halpha      228.9      0.18     -82    24
# Comp:  2             [SII]6716      29.82      0.18     -85    28
# Comp:  2             [SII]6731      20.11      0.18     -85    28
# Comp:  2              HeII4687     0.2791      0.18     -85    28
# Comp:  2               HeI5876      7.672      0.18     -85    28
# Comp:  2          [OIII]5007_d      57.04      0.23     -85    28
# Comp:  2            [OI]6300_d      3.396      0.23     -85    28
# Comp:  2           [NII]6583_d      63.71      0.23     -85    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -827      1000
#  comp.  1:       -81        20
#  comp.  2:       -82        20
# chi2/DOF: 2.724; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.99      0.18     -81    20
# Comp:  1                Halpha      228.6      0.18     -81    20
# Comp:  2             [SII]6716      29.51      0.18     -82    20
# Comp:  2             [SII]6731      19.17      0.18     -82    20
# Comp:  2              HeII4687     0.1513      0.18     -82    20
# Comp:  2               HeI5876      8.030      0.18     -82    20
# Comp:  2          [OIII]5007_d      53.27      0.22     -82    20
# Comp:  2            [OI]6300_d      2.743      0.22     -82    20
# Comp:  2           [NII]6583_d      60.77      0.22     -82    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -603      1000
#  comp.  1:       -81        23
#  comp.  2:       -85        29
# chi2/DOF: 2.637; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.95      0.18     -81    23
# Comp:  1                Halpha      227.9      0.18     -81    23
# Comp:  2             [SII]6716      30.10      0.18     -85    29
# Comp:  2             [SII]6731      19.57      0.18     -85    29
# Comp:  2              HeII4687     0.1584      0.18     -85    29
# Comp:  2               HeI5876      7.720      0.18     -85    29
# Comp:  2          [OIII]5007_d      56.68      0.23     -85    29
# Comp:  2            [OI]6300_d      2.951      0.23     -85    29
# Comp:  2           [NII]6583_d      62.36      0.23     -85    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -983       290
#  comp.  1:       -83        25
#  comp.  2:       -83        25
# chi2/DOF: 2.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      34.85      0.18     -83    25
# Comp:  1                Halpha      234.6      0.18     -83    25
# Comp:  2             [SII]6716      29.19      0.18     -83    25
# Comp:  2             [SII]6731      20.01      0.18     -83    25
# Comp:  2              HeII4687     0.2619      0.18     -83    25
# Comp:  2               HeI5876      7.515      0.18     -83    25
# Comp:  2          [OIII]5007_d      52.53      0.22     -83    25
# Comp:  2            [OI]6300_d      3.066      0.22     -83    25
# Comp:  2           [NII]6583_d      61.49      0.22     -83    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63       750
#  comp.  1:       -83        23
#  comp.  2:       -84        29
# chi2/DOF: 2.149; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.50      0.18     -83    23
# Comp:  1                Halpha      233.9      0.18     -83    23
# Comp:  2             [SII]6716      28.92      0.18     -84    29
# Comp:  2             [SII]6731      20.05      0.18     -84    29
# Comp:  2              HeII4687     0.1102      0.18     -84    29
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.12      0.18     -81    23
# Comp:  1                Halpha      227.8      0.18     -81    23
# Comp:  2             [SII]6716      28.58      0.17     -82    17
# Comp:  2             [SII]6731      19.79      0.17     -82    17
# Comp:  2              HeII4687    0.07858      0.17     -82    17
# Comp:  2               HeI5876      7.401      0.17     -82    17
# Comp:  2          [OIII]5007_d      51.98      0.22     -82    17
# Comp:  2            [OI]6300_d      3.236      0.22     -82    17
# Comp:  2           [NII]6583_d      60.80      0.22     -82    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -557      1000
#  comp.  1:       -83        26
#  comp.  2:       -81        25
# chi2/DOF: 2.702; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.49      0.18     -83    26
# Comp:  1                Halpha      233.2      0.18     -83    26
# Comp:  2             [SII]6716      29.47      0.18     -81    25
# Comp:  2             [SII]6731      19.76      0.18     -81    25
# Comp:  2              HeII4687     0.1819      0.18     -81    25
# Comp:  2               HeI5876      7.413      0.18     -81    25
# Comp:  2          [OIII]5007_d      53.21      0.22     -81    25
# Comp:  2            [OI]6300_d      3.409      0.22     -81    25
# Comp:  2           [NII]6583_d      61.53      0.22     -81    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -454       994
#  comp.  1:       -82        27
#  comp.  2:       -85        28
# chi2/DOF: 2.737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.06      0.18     -82    27
# Comp:  1                Halpha      233.7      0.18     -82    27
# Comp:  2             [SII]6716      28.96      0.18     -85    28
# Comp:  2             [SII]6731      20.16      0.18     -85    28
# Comp:  2              HeII4687     0.1515      0.18     -85    28
# Comp:  2               HeI5876      8.363      0.18     -85    28
# Comp:  2          [OIII]5007_d      54.22      0.23     -85    28
# Comp:  2            [OI]6300_d      3.271      0.23     -85    28
# Comp:  2           [NII]6583_d      64.05      0.23     -85    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       206
#  comp.  1:       -82        24
#  comp.  2:       -84         6
# chi2/DOF: 2.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.02      0.18     -82    24
# Comp:  1                Halpha      231.1      0.18     -82    24
# Comp:  2             [SII]6716      28.85      0.17     -84     6
# Comp:  2             [SII]6731      19.24      0.17     -84     6
# Comp:  2              HeII4687     0.1865      0.17     -84     6
# Comp:  2               HeI5876      7.282      0.17     -84     6
# Comp:  2          [OIII]5007_d      50.99      0.22     -84     6
# Comp:  2            [OI]6300_d      3.200      0.22     -84     6
# Comp:  2           [NII]6583_d      60.46      0.22     -84     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -192      1000
#  comp.  1:       -83        20
#  comp.  2:       -85        23
# chi2/DOF: 2.442; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.40      0.18     -83    20
# Comp:  1                Halpha      230.5      0.18     -83    20
# Comp:  2             [SII]6716      29.35      0.18     -85    23
# Comp:  2             [SII]6731      20.42      0.18     -85    23
# Comp:  2              HeII4687     0.1441      0.18     -85    23
# Comp:  2               HeI5876      7.254      0.18     -85    23
# Comp:  2          [OIII]5007_d      52.63      0.22     -85    23
# Comp:  2            [OI]6300_d      3.090      0.22     -85    23
# Comp:  2           [NII]6583_d      63.21      0.22     -85    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73         1
#  comp.  1:       -82        22
#  comp.  2:       -84         9
# chi2/DOF: 2.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 22; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.09      0.18     -82    22
# Comp:  1                Halpha      231.1      0.18     -82    22
# Comp:  2             [SII]6716      28.20      0.17     -84     9
# Comp:  2             [SII]6731      19.49      0.17     -84     9
# Comp:  2              HeII4687    0.06133      0.17     -84     9
# Comp:  2               HeI5876      7.332      0.17     -84     9
# Comp:  2          [OIII]5007_d      51.25      0.22     -84     9
# Comp:  2            [OI]6300_d      2.624      0.22     -84     9
# Comp:  2           [NII]6583_d      60.91      0.22     -84     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -803      1000
#  comp.  1:       -81        23
#  comp.  2:       -82        22
# chi2/DOF: 2.822; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.22      0.18     -81    23
# Comp:  1                Halpha      229.6      0.18     -81    23
# Comp:  2             [SII]6716      28.58      0.18     -82    22
# Comp:  2             [SII]6731      19.38      0.18     -82    22
# Comp:  2              HeII4687     0.3023      0.18     -82    22
# Comp:  2               HeI5876      8.032      0.18     -82    22
# Comp:  2          [OIII]5007_d      53.28      0.22     -82    22
# Comp:  2            [OI]6300_d      2.944      0.22     -82    22
# Comp:  2           [NII]6583_d      62.85      0.22     -82    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -339      1000
#  comp.  1:       -83        23
#  comp.  2:       -85        19
# chi2/DOF: 2.706; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.31      0.18     -83    23
# Comp:  1                Halpha      233.8      0.18     -83    23
# Comp:  2             [SII]6716      29.64      0.18     -85    19
# Comp:  2             [SII]6731      19.43      0.18     -85    19
# Comp:  2              HeII4687     0.2903      0.18     -85    19
# Comp:  2               HeI5876      7.413      0.18     -85    19
# Comp:  2          [OIII]5007_d      54.06      0.22     -85    19
# Comp:  2            [OI]6300_d      3.090      0.22     -85    19
# Comp:  2           [NII]6583_d      62.62      0.22     -85    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -405      1000
#  comp.  1:       -83        25
#  comp.  2:       -86        33
# chi2/DOF: 2.151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.50      0.18     -83    25
# Comp:  1                Halpha      232.6      0.18     -83    25
# Comp:  2             [SII]6716      29.99      0.18     -86    33
# Comp:  2             [SII]6731      20.86      0.18     -86    33
# Comp:  2              HeII4687    0.09359      0.18     -86    33
# Comp:  2               HeI5876      8.096      0.18     -86    33
# Comp:  2          [OIII]5007_d      55.54      0.23     -86    33
# Comp:  2            [OI]6300_d      3.101      0.23     -86    33
# Comp:  2           [NII]6583_d      63.16      0.23     -86    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -551       903
#  comp.  1:       -82        27
#  comp.  2:       -82        17
# chi2/DOF: 2.674; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.38      0.18     -82    27
# Comp:  1                Halpha      234.0      0.18     -82    27
# Comp:  2             [SII]6716      29.54      0.17     -82    17
# Comp:  2             [SII]6731      19.29      0.17     -82    17
# Comp:  2              HeII4687    0.03851      0.17     -82    17
# Comp:  2               HeI5876      7.652      0.17     -82    17
# Comp:  2          [OIII]5007_d      52.99      0.22     -82    17
# Comp:  2            [OI]6300_d      3.337      0.22     -82    17
# Comp:  2           [NII]6583_d      60.65      0.22     -82    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -747         1
#  comp.  1:       -82        25
#  comp.  2:       -84        18
# chi2/DOF: 2.714; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.29      0.18     -82    25
# Comp:  1                Halpha      229.3      0.18     -82    25
# Comp:  2             [SII]6716      29.16      0.17     -84    18
# Comp:  2             [SII]6731      19.29      0.17     -84    18
# Comp:  2              HeII4687     0.1074      0.17     -84    18
# Comp:  2               HeI5876      7.502      0.17     -84    18
# Comp:  2          [OIII]5007_d      51.48      0.22     -84    18
# Comp:  2            [OI]6300_d      2.967      0.22     -84    18
# Comp:  2           [NII]6583_d      62.00      0.22     -84    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -506       948
#  comp.  1:       -82        18
#  comp.  2:       -84        17
# chi2/DOF: 2.062; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.03      0.17     -82    18
# Comp:  1                Halpha      227.4      0.17     -82    18
# Comp:  2             [SII]6716      28.52      0.17     -84    17
# Comp:  2             [SII]6731      19.45      0.17     -84    17
# Comp:  2              HeII4687     0.1301      0.17     -84    17
# Comp:  2               HeI5876      7.649      0.17     -84    17
# Comp:  2          [OIII]5007_d      50.85      0.22     -84    17
# Comp:  2            [OI]6300_d      3.242      0.22     -84    17
# Comp:  2           [NII]6583_d      61.30      0.22     -84    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -702       895
#  comp.  1:       -82        23
#  comp.  2:       -87        25
# chi2/DOF: 2.777; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.83      0.18     -82    23
# Comp:  1                Halpha      231.3      0.18     -82    23
# Comp:  2             [SII]6716      29.03      0.18     -87    25
# Comp:  2             [SII]6731      19.73      0.18     -87    25
# Comp:  2              HeII4687     0.1618      0.18     -87    25
# Comp:  2               HeI5876      7.300      0.18     -87    25
# Comp:  2          [OIII]5007_d      54.00      0.22     -87    25
# Comp:  2            [OI]6300_d      3.685      0.22     -87    25
# Comp:  2           [NII]6583_d      61.02      0.22     -87    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -505       776
#  comp.  1:       -83        27
#  comp.  2:       -87        27
# chi2/DOF: 2.614; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.23      0.18     -83    27
# Comp:  1                Halpha      233.8      0.18     -83    27
# Comp:  2             [SII]6716      30.46      0.18     -87    27
# Comp:  2             [SII]6731      19.96      0.18     -87    27
# Comp:  2              HeII4687     0.2745      0.18     -87    27
# Comp:  2               HeI5876      7.772      0.18     -87    27
# Comp:  2          [OIII]5007_d      54.71      0.23     -87    27
# Comp:  2            [OI]6300_d      3.587      0.23     -87    27
# Comp:  2           [NII]6583_d      63.07      0.23     -87    27
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([4.20225306, 2.87007246, 0.86184637, 0.75618474, 0.08318411,
#        0.39944339, 1.85219139, 0.34625794, 1.64191559])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([4.16762169e+01, 3.15817906e+02, 4.11897960e+01, 2.76575786e+01,
#        1.53469780e-01, 9.35341650e+00, 5.59978587e+01, 4.22456170e+00,
#        8.55411702e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_6_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_6", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_6_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_6_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_6_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta   2.396722    0.241664
# 1        Halpha  18.162099    0.165053
# 2     [SII]6716   2.368748    0.049563
# 3     [SII]6731   1.590536    0.043487
# 4      HeII4687   0.008826    0.004784
# 5       HeI5876   0.537898    0.022971
# 6  [OIII]5007_d   3.220332    0.106516
# 7    [OI]6300_d   0.242947    0.019913
# 8   [NII]6583_d   4.919313    0.094424
#           Name       Flux  Error_flux
# 0        Hbeta   2.396722    0.241664
# 1       Halpha  18.162099    0.165053
# 2    [SII]6716   2.368748    0.049563
# 3    [SII]6731   1.590536    0.043487
# 4     HeII4687   0.008826    0.004784
# 5      HeI5876   0.537898    0.022971
# 6   [OIII]4959   0.805083    0.106516
# 7   [OIII]5007   2.415249    0.106516
# 8     [OI]6300   0.182210    0.019913
# 9     [OI]6364   0.060737    0.019913
# 10   [NII]6548   1.229828    0.094424
# 11   [NII]6583   3.689485    0.094424

# %%
np.median(flux_rf_rebin)
# Out:
# 0.057508136342888025
