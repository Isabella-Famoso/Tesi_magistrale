# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [ 0.00965868  0.01032275 -0.00602203 ...  0.00969891  0.01191801
#   0.01075042] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
# chi2/DOF: 0.1302; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
# chi2/DOF: 0.05474; DOF: 1897; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-78.61176192,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -72        24
#  comp.  2:       -83        41
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.394      0.61     -72    24
# Comp:  1                Halpha      7.061      0.61     -72    24
# Comp:  2             [SII]6716      1.948      0.65     -83    41
# Comp:  2             [SII]6731      2.776      0.65     -83    41
# Comp:  2              HeII4687      0.000      0.65     -83    41
# Comp:  2               HeI5876     0.7708      0.65     -83    41
# Comp:  2          [OIII]5007_d      2.601      0.82     -83    41
# Comp:  2            [OI]6300_d      1.216      0.82     -83    41
# Comp:  2           [NII]6583_d      2.664      0.82     -83    41
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  4.537; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  9.935; gas flux:     10 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.578; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  3.557; gas flux:      4 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.013; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.521; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.146; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  2.624; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        60
#  comp.  1:       -68        47
#  comp.  2:       -86         1
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.163      0.66     -68    47
# Comp:  1                Halpha      7.930      0.66     -68    47
# Comp:  2             [SII]6716      1.737      0.60     -86     1
# Comp:  2             [SII]6731      2.260      0.60     -86     1
# Comp:  2              HeII4687    0.09100      0.60     -86     1
# Comp:  2               HeI5876     0.8311      0.60     -86     1
# Comp:  2          [OIII]5007_d      2.196      0.75     -86     1
# Comp:  2            [OI]6300_d      1.091      0.75     -86     1
# Comp:  2           [NII]6583_d      2.515      0.75     -86     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69       152
#  comp.  1:       -71        17
#  comp.  2:       -90        17
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.387      0.60     -71    17
# Comp:  1                Halpha      6.409      0.60     -71    17
# Comp:  2             [SII]6716      1.604      0.61     -90    17
# Comp:  2             [SII]6731      2.893      0.61     -90    17
# Comp:  2              HeII4687      0.000      0.61     -90    17
# Comp:  2               HeI5876      1.230      0.61     -90    17
# Comp:  2          [OIII]5007_d      1.656      0.76     -90    17
# Comp:  2            [OI]6300_d      1.053      0.76     -90    17
# Comp:  2           [NII]6583_d      2.287      0.76     -90    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        34
#  comp.  1:       -72        24
#  comp.  2:       -83        42
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.378      0.61     -72    24
# Comp:  1                Halpha      6.373      0.61     -72    24
# Comp:  2             [SII]6716      1.990      0.65     -83    42
# Comp:  2             [SII]6731      2.588      0.65     -83    42
# Comp:  2              HeII4687     0.3478      0.65     -83    42
# Comp:  2               HeI5876     0.7412      0.65     -83    42
# Comp:  2          [OIII]5007_d      2.227      0.82     -83    42
# Comp:  2            [OI]6300_d      1.483      0.82     -83    42
# Comp:  2           [NII]6583_d      2.608      0.82     -83    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -377       592
#  comp.  1:       -68        11
#  comp.  2:       -88        53
# chi2/DOF: 1.247; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.804      0.60     -68    11
# Comp:  1                Halpha      5.669      0.60     -68    11
# Comp:  2             [SII]6716      1.871      0.67     -88    53
# Comp:  2             [SII]6731      2.716      0.67     -88    53
# Comp:  2              HeII4687      0.000      0.67     -88    53
# Comp:  2               HeI5876     0.8175      0.67     -88    53
# Comp:  2          [OIII]5007_d      3.443      0.85     -88    53
# Comp:  2            [OI]6300_d      1.197      0.85     -88    53
# Comp:  2           [NII]6583_d      2.850      0.85     -88    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        36
#  comp.  1:       -72        24
#  comp.  2:       -84        41
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.137      0.61     -72    24
# Comp:  1                Halpha      6.751      0.61     -72    24
# Comp:  2             [SII]6716      1.941      0.65     -84    41
# Comp:  2             [SII]6731      2.988      0.65     -84    41
# Comp:  2              HeII4687      0.000      0.65     -84    41
# Comp:  2               HeI5876     0.6374      0.65     -84    41
# Comp:  2          [OIII]5007_d      2.842      0.82     -84    41
# Comp:  2            [OI]6300_d      1.469      0.82     -84    41
# Comp:  2           [NII]6583_d      2.436      0.82     -84    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        51
#  comp.  1:       -71        24
#  comp.  2:       -82        40
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.193      0.61     -71    24
# Comp:  1                Halpha      6.569      0.61     -71    24
# Comp:  2             [SII]6716      2.048      0.64     -82    40
# Comp:  2             [SII]6731      2.861      0.64     -82    40
# Comp:  2              HeII4687      0.000      0.64     -82    40
# Comp:  2               HeI5876     0.9756      0.64     -82    40
# Comp:  2          [OIII]5007_d      2.262      0.81     -82    40
# Comp:  2            [OI]6300_d      1.204      0.81     -82    40
# Comp:  2           [NII]6583_d      2.443      0.81     -82    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -68        28
#  comp.  2:       -87         1
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.309      0.62     -68    28
# Comp:  1                Halpha      7.069      0.62     -68    28
# Comp:  2             [SII]6716      1.499      0.60     -87     1
# Comp:  2             [SII]6731      2.128      0.60     -87     1
# Comp:  2              HeII4687      0.000      0.60     -87     1
# Comp:  2               HeI5876     0.9295      0.60     -87     1
# Comp:  2          [OIII]5007_d      2.940      0.75     -87     1
# Comp:  2            [OI]6300_d      1.340      0.75     -87     1
# Comp:  2           [NII]6583_d      2.300      0.75     -87     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        33
#  comp.  1:       -73        24
#  comp.  2:       -69        97
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.580      0.61     -73    24
# Comp:  1                Halpha      7.173      0.61     -73    24
# Comp:  2             [SII]6716      2.522      0.79     -69    97
# Comp:  2             [SII]6731      3.589      0.79     -69    97
# Comp:  2              HeII4687     0.3015      0.79     -69    97
# Comp:  2               HeI5876      1.790      0.79     -69    97
# Comp:  2          [OIII]5007_d      3.478       1.0     -69    97
# Comp:  2            [OI]6300_d      1.357       1.0     -69    97
# Comp:  2           [NII]6583_d      3.178       1.0     -69    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        48
#  comp.  1:       -67        41
#  comp.  2:       -92        20
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.513      0.65     -67    41
# Comp:  1                Halpha      7.403      0.65     -67    41
# Comp:  2             [SII]6716      1.964      0.61     -92    20
# Comp:  2             [SII]6731      2.556      0.61     -92    20
# Comp:  2              HeII4687     0.3738      0.61     -92    20
# Comp:  2               HeI5876      1.338      0.61     -92    20
# Comp:  2          [OIII]5007_d      2.796      0.77     -92    20
# Comp:  2            [OI]6300_d      1.009      0.77     -92    20
# Comp:  2           [NII]6583_d      2.243      0.77     -92    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -72        28
#  comp.  2:       -90        59
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.526      0.62     -72    28
# Comp:  1                Halpha      7.360      0.62     -72    28
# Comp:  2             [SII]6716      2.231      0.69     -90    59
# Comp:  2             [SII]6731      2.828      0.69     -90    59
# Comp:  2              HeII4687      0.000      0.69     -90    59
# Comp:  2               HeI5876     0.8748      0.69     -90    59
# Comp:  2          [OIII]5007_d      2.201      0.87     -90    59
# Comp:  2            [OI]6300_d      1.392      0.87     -90    59
# Comp:  2           [NII]6583_d      2.784      0.87     -90    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:       -78        20
#  comp.  2:       -76        39
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.751      0.61     -78    20
# Comp:  1                Halpha      7.318      0.61     -78    20
# Comp:  2             [SII]6716      1.784      0.64     -76    39
# Comp:  2             [SII]6731      2.911      0.64     -76    39
# Comp:  2              HeII4687     0.5477      0.64     -76    39
# Comp:  2               HeI5876     0.1315      0.64     -76    39
# Comp:  2          [OIII]5007_d      2.404      0.81     -76    39
# Comp:  2            [OI]6300_d      1.339      0.81     -76    39
# Comp:  2           [NII]6583_d      2.859      0.81     -76    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -72        39
#  comp.  2:       -75        36
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.548      0.64     -72    39
# Comp:  1                Halpha      7.687      0.64     -72    39
# Comp:  2             [SII]6716      2.221      0.64     -75    36
# Comp:  2             [SII]6731      2.797      0.64     -75    36
# Comp:  2              HeII4687      0.000      0.64     -75    36
# Comp:  2               HeI5876     0.9720      0.64     -75    36
# Comp:  2          [OIII]5007_d      2.064      0.80     -75    36
# Comp:  2            [OI]6300_d      1.107      0.80     -75    36
# Comp:  2           [NII]6583_d      2.706      0.80     -75    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        84
#  comp.  1:       -68        42
#  comp.  2:       -84        36
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.488      0.65     -68    42
# Comp:  1                Halpha      7.445      0.65     -68    42
# Comp:  2             [SII]6716      2.096      0.64     -84    36
# Comp:  2             [SII]6731      2.580      0.64     -84    36
# Comp:  2              HeII4687     0.4082      0.64     -84    36
# Comp:  2               HeI5876      1.471      0.64     -84    36
# Comp:  2          [OIII]5007_d      3.434      0.80     -84    36
# Comp:  2            [OI]6300_d      1.189      0.80     -84    36
# Comp:  2           [NII]6583_d      2.516      0.80     -84    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        78
#  comp.  1:       -71        25
#  comp.  2:       -83        41
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.393      0.62     -71    25
# Comp:  1                Halpha      6.506      0.62     -71    25
# Comp:  2             [SII]6716      2.177      0.65     -83    41
# Comp:  2             [SII]6731      2.640      0.65     -83    41
# Comp:  2              HeII4687      0.000      0.65     -83    41
# Comp:  2               HeI5876     0.8676      0.65     -83    41
# Comp:  2          [OIII]5007_d      3.371      0.82     -83    41
# Comp:  2            [OI]6300_d      1.117      0.82     -83    41
# Comp:  2           [NII]6583_d      2.649      0.82     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59       360
#  comp.  1:       -71         1
#  comp.  2:       -82        44
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.865      0.60     -71     1
# Comp:  1                Halpha      5.883      0.60     -71     1
# Comp:  2             [SII]6716      1.853      0.65     -82    44
# Comp:  2             [SII]6731      3.452      0.65     -82    44
# Comp:  2              HeII4687      0.000      0.65     -82    44
# Comp:  2               HeI5876     0.1267      0.65     -82    44
# Comp:  2          [OIII]5007_d      1.866      0.82     -82    44
# Comp:  2            [OI]6300_d      1.126      0.82     -82    44
# Comp:  2           [NII]6583_d      3.078      0.82     -82    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        43
#  comp.  1:       -71        24
#  comp.  2:       -82        41
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.776      0.61     -71    24
# Comp:  1                Halpha      6.550      0.61     -71    24
# Comp:  2             [SII]6716      2.077      0.65     -82    41
# Comp:  2             [SII]6731      3.226      0.65     -82    41
# Comp:  2              HeII4687     0.4697      0.65     -82    41
# Comp:  2               HeI5876      1.477      0.65     -82    41
# Comp:  2          [OIII]5007_d      1.849      0.82     -82    41
# Comp:  2            [OI]6300_d      1.136      0.82     -82    41
# Comp:  2           [NII]6583_d      2.450      0.82     -82    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       -79        34
#  comp.  2:       -85        48
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.427      0.63     -79    34
# Comp:  1                Halpha      7.123      0.63     -79    34
# Comp:  2             [SII]6716      2.301      0.66     -85    48
# Comp:  2             [SII]6731      2.642      0.66     -85    48
# Comp:  2              HeII4687     0.2740      0.66     -85    48
# Comp:  2               HeI5876      1.623      0.66     -85    48
# Comp:  2          [OIII]5007_d      2.285      0.84     -85    48
# Comp:  2            [OI]6300_d      1.173      0.84     -85    48
# Comp:  2           [NII]6583_d      2.732      0.84     -85    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -117         1
#  comp.  1:       -77         1
#  comp.  2:       -84        22
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.140      0.60     -77     1
# Comp:  1                Halpha      5.990      0.60     -77     1
# Comp:  2             [SII]6716      1.956      0.61     -84    22
# Comp:  2             [SII]6731      3.044      0.61     -84    22
# Comp:  2              HeII4687      0.000      0.61     -84    22
# Comp:  2               HeI5876     0.8481      0.61     -84    22
# Comp:  2          [OIII]5007_d      1.958      0.77     -84    22
# Comp:  2            [OI]6300_d      1.039      0.77     -84    22
# Comp:  2           [NII]6583_d      2.407      0.77     -84    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -73        11
#  comp.  2:       -89        41
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.405      0.60     -73    11
# Comp:  1                Halpha      6.953      0.60     -73    11
# Comp:  2             [SII]6716      1.690      0.65     -89    41
# Comp:  2             [SII]6731      2.673      0.65     -89    41
# Comp:  2              HeII4687      0.000      0.65     -89    41
# Comp:  2               HeI5876      1.520      0.65     -89    41
# Comp:  2          [OIII]5007_d      1.868      0.82     -89    41
# Comp:  2            [OI]6300_d      1.281      0.82     -89    41
# Comp:  2           [NII]6583_d      2.873      0.82     -89    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        32
#  comp.  1:       -72        24
#  comp.  2:       -84        40
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.056      0.61     -72    24
# Comp:  1                Halpha      7.046      0.61     -72    24
# Comp:  2             [SII]6716      2.169      0.64     -84    40
# Comp:  2             [SII]6731      2.259      0.64     -84    40
# Comp:  2              HeII4687      0.000      0.64     -84    40
# Comp:  2               HeI5876      1.427      0.64     -84    40
# Comp:  2          [OIII]5007_d      3.080      0.81     -84    40
# Comp:  2            [OI]6300_d      1.336      0.81     -84    40
# Comp:  2           [NII]6583_d      2.583      0.81     -84    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        60
#  comp.  1:       -71        25
#  comp.  2:       -83        41
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.719      0.62     -71    25
# Comp:  1                Halpha      7.353      0.62     -71    25
# Comp:  2             [SII]6716      2.142      0.65     -83    41
# Comp:  2             [SII]6731      2.682      0.65     -83    41
# Comp:  2              HeII4687     0.4786      0.65     -83    41
# Comp:  2               HeI5876     0.8467      0.65     -83    41
# Comp:  2          [OIII]5007_d      1.861      0.82     -83    41
# Comp:  2            [OI]6300_d      1.447      0.82     -83    41
# Comp:  2           [NII]6583_d      3.054      0.82     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        25
#  comp.  1:       -72        23
#  comp.  2:       -84        40
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.877      0.61     -72    23
# Comp:  1                Halpha      6.228      0.61     -72    23
# Comp:  2             [SII]6716      1.640      0.64     -84    40
# Comp:  2             [SII]6731      2.497      0.64     -84    40
# Comp:  2              HeII4687      0.000      0.64     -84    40
# Comp:  2               HeI5876     0.1024      0.64     -84    40
# Comp:  2          [OIII]5007_d      2.696      0.81     -84    40
# Comp:  2            [OI]6300_d     0.9839      0.81     -84    40
# Comp:  2           [NII]6583_d      2.396      0.81     -84    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        20
#  comp.  1:       -71        24
#  comp.  2:       -82        42
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.836      0.61     -71    24
# Comp:  1                Halpha      7.256      0.61     -71    24
# Comp:  2             [SII]6716      1.653      0.65     -82    42
# Comp:  2             [SII]6731      2.959      0.65     -82    42
# Comp:  2              HeII4687      0.000      0.65     -82    42
# Comp:  2               HeI5876     0.5719      0.65     -82    42
# Comp:  2          [OIII]5007_d      2.118      0.82     -82    42
# Comp:  2            [OI]6300_d      1.236      0.82     -82    42
# Comp:  2           [NII]6583_d      2.711      0.82     -82    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -68        33
#  comp.  2:       -88        30
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.810      0.63     -68    33
# Comp:  1                Halpha      7.411      0.63     -68    33
# Comp:  2             [SII]6716      2.106      0.62     -88    30
# Comp:  2             [SII]6731      2.397      0.62     -88    30
# Comp:  2              HeII4687     0.5010      0.62     -88    30
# Comp:  2               HeI5876     0.1270      0.62     -88    30
# Comp:  2          [OIII]5007_d      2.815      0.79     -88    30
# Comp:  2            [OI]6300_d      1.266      0.79     -88    30
# Comp:  2           [NII]6583_d      2.783      0.79     -88    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -67        39
#  comp.  2:       -71        68
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.530      0.64     -67    39
# Comp:  1                Halpha      7.386      0.64     -67    39
# Comp:  2             [SII]6716      2.005      0.71     -71    68
# Comp:  2             [SII]6731      3.253      0.71     -71    68
# Comp:  2              HeII4687    0.09757      0.71     -71    68
# Comp:  2               HeI5876     0.8511      0.71     -71    68
# Comp:  2          [OIII]5007_d      3.112      0.90     -71    68
# Comp:  2            [OI]6300_d      1.539      0.90     -71    68
# Comp:  2           [NII]6583_d      2.783      0.90     -71    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -69         6
#  comp.  2:       -97        38
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.976      0.60     -69     6
# Comp:  1                Halpha      6.517      0.60     -69     6
# Comp:  2             [SII]6716      2.237      0.64     -97    38
# Comp:  2             [SII]6731      2.468      0.64     -97    38
# Comp:  2              HeII4687     0.5181      0.64     -97    38
# Comp:  2               HeI5876    0.07375      0.64     -97    38
# Comp:  2          [OIII]5007_d      3.132      0.81     -97    38
# Comp:  2            [OI]6300_d      1.474      0.81     -97    38
# Comp:  2           [NII]6583_d      2.786      0.81     -97    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        18
#  comp.  1:       -72        24
#  comp.  2:       -83        42
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.892      0.61     -72    24
# Comp:  1                Halpha      7.156      0.61     -72    24
# Comp:  2             [SII]6716      1.996      0.65     -83    42
# Comp:  2             [SII]6731      3.292      0.65     -83    42
# Comp:  2              HeII4687    0.01929      0.65     -83    42
# Comp:  2               HeI5876      1.492      0.65     -83    42
# Comp:  2          [OIII]5007_d      3.323      0.82     -83    42
# Comp:  2            [OI]6300_d      1.158      0.82     -83    42
# Comp:  2           [NII]6583_d      2.991      0.82     -83    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -69        23
#  comp.  2:       -76        18
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.089      0.61     -69    23
# Comp:  1                Halpha      6.804      0.61     -69    23
# Comp:  2             [SII]6716      1.954      0.61     -76    18
# Comp:  2             [SII]6731      2.476      0.61     -76    18
# Comp:  2              HeII4687      0.000      0.61     -76    18
# Comp:  2               HeI5876     0.1427      0.61     -76    18
# Comp:  2          [OIII]5007_d      2.298      0.77     -76    18
# Comp:  2            [OI]6300_d     0.9844      0.77     -76    18
# Comp:  2           [NII]6583_d      2.625      0.77     -76    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -69        31
#  comp.  2:       -90        59
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.043      0.63     -69    31
# Comp:  1                Halpha      7.165      0.63     -69    31
# Comp:  2             [SII]6716      2.357      0.69     -90    59
# Comp:  2             [SII]6731      2.795      0.69     -90    59
# Comp:  2              HeII4687      0.000      0.69     -90    59
# Comp:  2               HeI5876      1.704      0.69     -90    59
# Comp:  2          [OIII]5007_d      3.244      0.87     -90    59
# Comp:  2            [OI]6300_d     0.8955      0.87     -90    59
# Comp:  2           [NII]6583_d      2.803      0.87     -90    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        97
#  comp.  1:       -70         4
#  comp.  2:       -80        65
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.605      0.60     -70     4
# Comp:  1                Halpha      6.125      0.60     -70     4
# Comp:  2             [SII]6716      1.916      0.70     -80    65
# Comp:  2             [SII]6731      2.923      0.70     -80    65
# Comp:  2              HeII4687      0.000      0.70     -80    65
# Comp:  2               HeI5876      1.525      0.70     -80    65
# Comp:  2          [OIII]5007_d      3.189      0.89     -80    65
# Comp:  2            [OI]6300_d      1.076      0.89     -80    65
# Comp:  2           [NII]6583_d      2.950      0.89     -80    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        46
#  comp.  1:       -72        25
#  comp.  2:       -83        42
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.543      0.62     -72    25
# Comp:  1                Halpha      6.486      0.62     -72    25
# Comp:  2             [SII]6716      1.817      0.65     -83    42
# Comp:  2             [SII]6731      2.557      0.65     -83    42
# Comp:  2              HeII4687      0.000      0.65     -83    42
# Comp:  2               HeI5876     0.4106      0.65     -83    42
# Comp:  2          [OIII]5007_d      2.477      0.82     -83    42
# Comp:  2            [OI]6300_d      1.133      0.82     -83    42
# Comp:  2           [NII]6583_d      2.788      0.82     -83    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:       -73        29
#  comp.  2:       -95        26
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.098      0.62     -73    29
# Comp:  1                Halpha      7.229      0.62     -73    29
# Comp:  2             [SII]6716      2.045      0.62     -95    26
# Comp:  2             [SII]6731      2.237      0.62     -95    26
# Comp:  2              HeII4687      0.000      0.62     -95    26
# Comp:  2               HeI5876      1.358      0.62     -95    26
# Comp:  2          [OIII]5007_d      2.671      0.78     -95    26
# Comp:  2            [OI]6300_d      1.027      0.78     -95    26
# Comp:  2           [NII]6583_d      2.610      0.78     -95    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        36
#  comp.  1:       -71        24
#  comp.  2:       -83        41
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.569      0.61     -71    24
# Comp:  1                Halpha      7.285      0.61     -71    24
# Comp:  2             [SII]6716      2.309      0.65     -83    41
# Comp:  2             [SII]6731      3.228      0.65     -83    41
# Comp:  2              HeII4687      0.000      0.65     -83    41
# Comp:  2               HeI5876      0.000      0.65     -83    41
# Comp:  2          [OIII]5007_d      2.732      0.82     -83    41
# Comp:  2            [OI]6300_d      1.470      0.82     -83    41
# Comp:  2           [NII]6583_d      2.491      0.82     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -71         1
#  comp.  2:       -76        49
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.127      0.60     -71     1
# Comp:  1                Halpha      6.588      0.60     -71     1
# Comp:  2             [SII]6716      2.014      0.66     -76    49
# Comp:  2             [SII]6731      2.888      0.66     -76    49
# Comp:  2              HeII4687      0.000      0.66     -76    49
# Comp:  2               HeI5876      1.423      0.66     -76    49
# Comp:  2          [OIII]5007_d      1.893      0.84     -76    49
# Comp:  2            [OI]6300_d      1.321      0.84     -76    49
# Comp:  2           [NII]6583_d      2.906      0.84     -76    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65       130
#  comp.  1:       -72        24
#  comp.  2:       -83        42
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.240      0.61     -72    24
# Comp:  1                Halpha      6.613      0.61     -72    24
# Comp:  2             [SII]6716      1.617      0.65     -83    42
# Comp:  2             [SII]6731      2.838      0.65     -83    42
# Comp:  2              HeII4687     0.3285      0.65     -83    42
# Comp:  2               HeI5876     0.7065      0.65     -83    42
# Comp:  2          [OIII]5007_d      1.800      0.82     -83    42
# Comp:  2            [OI]6300_d      1.072      0.82     -83    42
# Comp:  2           [NII]6583_d      2.624      0.82     -83    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116        80
#  comp.  1:       -81        47
#  comp.  2:       -88        17
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.039      0.66     -81    47
# Comp:  1                Halpha      7.510      0.66     -81    47
# Comp:  2             [SII]6716      1.786      0.61     -88    17
# Comp:  2             [SII]6731      2.160      0.61     -88    17
# Comp:  2              HeII4687     0.2282      0.61     -88    17
# Comp:  2               HeI5876     0.8919      0.61     -88    17
# Comp:  2          [OIII]5007_d      2.492      0.76     -88    17
# Comp:  2            [OI]6300_d      1.087      0.76     -88    17
# Comp:  2           [NII]6583_d      2.344      0.76     -88    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        43
#  comp.  1:       -72        23
#  comp.  2:       -83        39
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.352      0.61     -72    23
# Comp:  1                Halpha      6.726      0.61     -72    23
# Comp:  2             [SII]6716      1.828      0.64     -83    39
# Comp:  2             [SII]6731      3.159      0.64     -83    39
# Comp:  2              HeII4687     0.3724      0.64     -83    39
# Comp:  2               HeI5876     0.1149      0.64     -83    39
# Comp:  2          [OIII]5007_d      1.932      0.81     -83    39
# Comp:  2            [OI]6300_d      1.307      0.81     -83    39
# Comp:  2           [NII]6583_d      2.775      0.81     -83    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -72        29
#  comp.  2:       -93        13
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.935      0.62     -72    29
# Comp:  1                Halpha      7.521      0.62     -72    29
# Comp:  2             [SII]6716      1.772      0.60     -93    13
# Comp:  2             [SII]6731      2.615      0.60     -93    13
# Comp:  2              HeII4687    0.07161      0.60     -93    13
# Comp:  2               HeI5876     0.6024      0.60     -93    13
# Comp:  2          [OIII]5007_d      2.645      0.76     -93    13
# Comp:  2            [OI]6300_d      1.466      0.76     -93    13
# Comp:  2           [NII]6583_d      2.189      0.76     -93    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -68        10
#  comp.  2:       -88         1
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.665      0.60     -68    10
# Comp:  1                Halpha      7.241      0.60     -68    10
# Comp:  2             [SII]6716      1.567      0.60     -88     1
# Comp:  2             [SII]6731      2.814      0.60     -88     1
# Comp:  2              HeII4687      0.000      0.60     -88     1
# Comp:  2               HeI5876    0.04809      0.60     -88     1
# Comp:  2          [OIII]5007_d      1.606      0.75     -88     1
# Comp:  2            [OI]6300_d      1.124      0.75     -88     1
# Comp:  2           [NII]6583_d      2.551      0.75     -88     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        19
#  comp.  1:       -72        23
#  comp.  2:       -83        43
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.794      0.61     -72    23
# Comp:  1                Halpha      6.618      0.61     -72    23
# Comp:  2             [SII]6716      1.674      0.65     -83    43
# Comp:  2             [SII]6731      2.932      0.65     -83    43
# Comp:  2              HeII4687      0.000      0.65     -83    43
# Comp:  2               HeI5876     0.5306      0.65     -83    43
# Comp:  2          [OIII]5007_d      2.664      0.82     -83    43
# Comp:  2            [OI]6300_d      1.267      0.82     -83    43
# Comp:  2           [NII]6583_d      2.429      0.82     -83    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -73        51
#  comp.  2:       -89        37
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.119      0.67     -73    51
# Comp:  1                Halpha      7.783      0.67     -73    51
# Comp:  2             [SII]6716      2.199      0.64     -89    37
# Comp:  2             [SII]6731      2.958      0.64     -89    37
# Comp:  2              HeII4687     0.2306      0.64     -89    37
# Comp:  2               HeI5876      1.398      0.64     -89    37
# Comp:  2          [OIII]5007_d      2.363      0.80     -89    37
# Comp:  2            [OI]6300_d     0.7720      0.80     -89    37
# Comp:  2           [NII]6583_d      2.679      0.80     -89    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35       211
#  comp.  1:       -73        46
#  comp.  2:       -98        59
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.276      0.66     -73    46
# Comp:  1                Halpha      7.164      0.66     -73    46
# Comp:  2             [SII]6716      2.098      0.69     -98    59
# Comp:  2             [SII]6731      3.074      0.69     -98    59
# Comp:  2              HeII4687      0.000      0.69     -98    59
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.493      0.61     -72    23
# Comp:  1                Halpha      6.580      0.61     -72    23
# Comp:  2             [SII]6716      1.617      0.65     -84    41
# Comp:  2             [SII]6731      2.665      0.65     -84    41
# Comp:  2              HeII4687      0.000      0.65     -84    41
# Comp:  2               HeI5876      1.511      0.65     -84    41
# Comp:  2          [OIII]5007_d      2.848      0.82     -84    41
# Comp:  2            [OI]6300_d      1.215      0.82     -84    41
# Comp:  2           [NII]6583_d      2.657      0.82     -84    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -78        45
#  comp.  2:       -95        51
# chi2/DOF: 1.253; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.998      0.66     -78    45
# Comp:  1                Halpha      7.600      0.66     -78    45
# Comp:  2             [SII]6716      1.988      0.67     -95    51
# Comp:  2             [SII]6731      2.702      0.67     -95    51
# Comp:  2              HeII4687     0.3773      0.67     -95    51
# Comp:  2               HeI5876      1.522      0.67     -95    51
# Comp:  2          [OIII]5007_d      2.420      0.84     -95    51
# Comp:  2            [OI]6300_d      1.188      0.84     -95    51
# Comp:  2           [NII]6583_d      2.623      0.84     -95    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -74        30
#  comp.  2:       -71        43
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.705      0.62     -74    30
# Comp:  1                Halpha      7.273      0.62     -74    30
# Comp:  2             [SII]6716      1.776      0.65     -71    43
# Comp:  2             [SII]6731      2.924      0.65     -71    43
# Comp:  2              HeII4687      0.000      0.65     -71    43
# Comp:  2               HeI5876     0.1095      0.65     -71    43
# Comp:  2          [OIII]5007_d      2.776      0.82     -71    43
# Comp:  2            [OI]6300_d      1.326      0.82     -71    43
# Comp:  2           [NII]6583_d      2.826      0.82     -71    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        42
#  comp.  1:       -74        16
#  comp.  2:       -83        19
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.317      0.60     -74    16
# Comp:  1                Halpha      7.020      0.60     -74    16
# Comp:  2             [SII]6716      1.762      0.61     -83    19
# Comp:  2             [SII]6731      2.224      0.61     -83    19
# Comp:  2              HeII4687     0.3111      0.61     -83    19
# Comp:  2               HeI5876     0.7143      0.61     -83    19
# Comp:  2          [OIII]5007_d      3.014      0.77     -83    19
# Comp:  2            [OI]6300_d      1.029      0.77     -83    19
# Comp:  2           [NII]6583_d      2.648      0.77     -83    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        75
#  comp.  1:       -67        32
#  comp.  2:       -87        66
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.405      0.63     -67    32
# Comp:  1                Halpha      7.254      0.63     -67    32
# Comp:  2             [SII]6716      1.966      0.71     -87    66
# Comp:  2             [SII]6731      2.312      0.71     -87    66
# Comp:  2              HeII4687      0.000      0.71     -87    66
# Comp:  2               HeI5876     0.8112      0.71     -87    66
# Comp:  2          [OIII]5007_d      2.733      0.89     -87    66
# Comp:  2            [OI]6300_d      1.456      0.89     -87    66
# Comp:  2           [NII]6583_d      3.248      0.89     -87    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -74        42
#  comp.  2:       -78         1
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.802      0.65     -74    42
# Comp:  1                Halpha      7.305      0.65     -74    42
# Comp:  2             [SII]6716      1.480      0.60     -78     1
# Comp:  2             [SII]6731      2.310      0.60     -78     1
# Comp:  2              HeII4687      0.000      0.60     -78     1
# Comp:  2               HeI5876     0.8605      0.60     -78     1
# Comp:  2          [OIII]5007_d      2.046      0.75     -78     1
# Comp:  2            [OI]6300_d      1.305      0.75     -78     1
# Comp:  2           [NII]6583_d      2.154      0.75     -78     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -69        23
#  comp.  2:       -84        62
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.144      0.61     -69    23
# Comp:  1                Halpha      6.631      0.61     -69    23
# Comp:  2             [SII]6716      2.487      0.70     -84    62
# Comp:  2             [SII]6731      3.143      0.70     -84    62
# Comp:  2              HeII4687     0.1207      0.70     -84    62
# Comp:  2               HeI5876     0.1110      0.70     -84    62
# Comp:  2          [OIII]5007_d      2.621      0.88     -84    62
# Comp:  2            [OI]6300_d      1.494      0.88     -84    62
# Comp:  2           [NII]6583_d      2.795      0.88     -84    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -72        24
#  comp.  2:       -83        41
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.374      0.61     -72    24
# Comp:  1                Halpha      6.941      0.61     -72    24
# Comp:  2             [SII]6716      1.595      0.65     -83    41
# Comp:  2             [SII]6731      2.634      0.65     -83    41
# Comp:  2              HeII4687     0.1062      0.65     -83    41
# Comp:  2               HeI5876      1.515      0.65     -83    41
# Comp:  2          [OIII]5007_d      2.901      0.82     -83    41
# Comp:  2            [OI]6300_d      1.384      0.82     -83    41
# Comp:  2           [NII]6583_d      2.589      0.82     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:       -69        38
#  comp.  2:       -72        29
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.333      0.64     -69    38
# Comp:  1                Halpha      6.791      0.64     -69    38
# Comp:  2             [SII]6716      1.833      0.62     -72    29
# Comp:  2             [SII]6731      2.467      0.62     -72    29
# Comp:  2              HeII4687      0.000      0.62     -72    29
# Comp:  2               HeI5876     0.9281      0.62     -72    29
# Comp:  2          [OIII]5007_d      2.369      0.79     -72    29
# Comp:  2            [OI]6300_d     0.8919      0.79     -72    29
# Comp:  2           [NII]6583_d      2.449      0.79     -72    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60       138
#  comp.  1:       -76        47
#  comp.  2:       -76        48
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.897      0.66     -76    47
# Comp:  1                Halpha      7.283      0.66     -76    47
# Comp:  2             [SII]6716      1.858      0.66     -76    48
# Comp:  2             [SII]6731      2.683      0.66     -76    48
# Comp:  2              HeII4687      0.000      0.66     -76    48
# Comp:  2               HeI5876      0.000      0.66     -76    48
# Comp:  2          [OIII]5007_d      1.542      0.84     -76    48
# Comp:  2            [OI]6300_d      1.185      0.84     -76    48
# Comp:  2           [NII]6583_d      2.893      0.84     -76    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -74        24
#  comp.  2:       -83        10
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.656      0.62     -74    24
# Comp:  1                Halpha      7.160      0.62     -74    24
# Comp:  2             [SII]6716      1.823      0.60     -83    10
# Comp:  2             [SII]6731      2.465      0.60     -83    10
# Comp:  2              HeII4687      0.000      0.60     -83    10
# Comp:  2               HeI5876     0.7613      0.60     -83    10
# Comp:  2          [OIII]5007_d      2.817      0.76     -83    10
# Comp:  2            [OI]6300_d      1.044      0.76     -83    10
# Comp:  2           [NII]6583_d      2.429      0.76     -83    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       -75        26
#  comp.  2:       -78         6
# chi2/DOF: 1.248; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.664      0.62     -75    26
# Comp:  1                Halpha      7.219      0.62     -75    26
# Comp:  2             [SII]6716      1.717      0.60     -78     6
# Comp:  2             [SII]6731      2.569      0.60     -78     6
# Comp:  2              HeII4687      0.000      0.60     -78     6
# Comp:  2               HeI5876    0.09210      0.60     -78     6
# Comp:  2          [OIII]5007_d      2.138      0.75     -78     6
# Comp:  2            [OI]6300_d      1.103      0.75     -78     6
# Comp:  2           [NII]6583_d      2.131      0.75     -78     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        30
#  comp.  1:       -72        24
#  comp.  2:       -83        43
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.354      0.61     -72    24
# Comp:  1                Halpha      6.718      0.61     -72    24
# Comp:  2             [SII]6716      2.276      0.65     -83    43
# Comp:  2             [SII]6731      2.887      0.65     -83    43
# Comp:  2              HeII4687     0.4303      0.65     -83    43
# Comp:  2               HeI5876     0.6381      0.65     -83    43
# Comp:  2          [OIII]5007_d      2.299      0.82     -83    43
# Comp:  2            [OI]6300_d      1.284      0.82     -83    43
# Comp:  2           [NII]6583_d      2.734      0.82     -83    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -78        33
#  comp.  2:       -81        39
# chi2/DOF: 1.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.085      0.63     -78    33
# Comp:  1                Halpha      6.766      0.63     -78    33
# Comp:  2             [SII]6716      1.853      0.64     -81    39
# Comp:  2             [SII]6731      2.732      0.64     -81    39
# Comp:  2              HeII4687     0.1113      0.64     -81    39
# Comp:  2               HeI5876     0.9340      0.64     -81    39
# Comp:  2          [OIII]5007_d      3.292      0.81     -81    39
# Comp:  2            [OI]6300_d      1.389      0.81     -81    39
# Comp:  2           [NII]6583_d      2.478      0.81     -81    39
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.5907377 , 0.65533067, 0.36574432, 0.57485416, 0.19594698,
#        0.60183045, 0.56442251, 0.24064918, 0.38826383])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([3.44164244, 9.66565682, 2.72919073, 3.89671032, 0.        ,
#        0.94466978, 2.71668049, 1.59732323, 3.65761378])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_1_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_1", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_1_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_1_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.045608    0.007828
# 1        Halpha  0.128089    0.008684
# 2     [SII]6716  0.036167    0.004847
# 3     [SII]6731  0.051639    0.007618
# 4      HeII4687  0.000000    0.002597
# 5       HeI5876  0.012519    0.007975
# 6  [OIII]5007_d  0.036001    0.007480
# 7    [OI]6300_d  0.021168    0.003189
# 8   [NII]6583_d  0.048471    0.005145
#           Name      Flux  Error_flux
# 0        Hbeta  0.045608    0.007828
# 1       Halpha  0.128089    0.008684
# 2    [SII]6716  0.036167    0.004847
# 3    [SII]6731  0.051639    0.007618
# 4     HeII4687  0.000000    0.002597
# 5      HeI5876  0.012519    0.007975
# 6   [OIII]4959  0.009000    0.007480
# 7   [OIII]5007  0.027001    0.007480
# 8     [OI]6300  0.015876    0.003189
# 9     [OI]6364  0.005292    0.003189
# 10   [NII]6548  0.012118    0.005145
# 11   [NII]6583  0.036353    0.005145

# %%
np.median(flux_rf_rebin)
# Out:
# 0.013251948753724839
