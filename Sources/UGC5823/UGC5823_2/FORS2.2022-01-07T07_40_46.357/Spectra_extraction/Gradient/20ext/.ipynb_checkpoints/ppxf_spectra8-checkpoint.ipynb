# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_8.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.0188 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_8']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4369.55241461 4371.00510404 4372.45779348 ... 6962.60306243 6964.05575186
#  6965.5084413 ] [0.01230979 0.02934796 0.02799371 ... 0.03104007 0.02764843 0.02220799] [0.0040752 0.0040752 0.0040752 ... 0.0040752 0.0040752 0.0040752]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.18477621 2.18550255 2.1862289  ... 3.48130153 3.48202788 3.48275422]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3151, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3151, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
# chi2/DOF: 0.02688; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        29
# chi2/DOF: 0.01629; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-53.00182977,  28.95844859])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        51
#  comp.  1:       -69        33
#  comp.  2:       -84        48
# chi2/DOF: 1.204; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.822      0.29     -69    33
# Comp:  1                Halpha      7.954      0.29     -69    33
# Comp:  2             [SII]6716      2.636      0.31     -84    48
# Comp:  2             [SII]6731      1.676      0.31     -84    48
# Comp:  2              HeII4687      0.000      0.31     -84    48
# Comp:  2               HeI5876     0.4120      0.31     -84    48
# Comp:  2          [OIII]5007_d      3.763      0.39     -84    48
# Comp:  2            [OI]6300_d     0.7967      0.39     -84    48
# Comp:  2           [NII]6583_d      3.840      0.39     -84    48
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  9.132; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   19.7; gas flux:     11 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  6.155; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  3.812; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.9533; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  6.426; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.337; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   6.69; gas flux:      5 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         9
#  comp.  1:       -70        32
#  comp.  2:       -71        58
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.328      0.29     -70    32
# Comp:  1                Halpha      7.962      0.29     -70    32
# Comp:  2             [SII]6716      2.793      0.32     -71    58
# Comp:  2             [SII]6731      1.769      0.32     -71    58
# Comp:  2              HeII4687     0.2977      0.32     -71    58
# Comp:  2               HeI5876     0.3834      0.32     -71    58
# Comp:  2          [OIII]5007_d      3.912      0.41     -71    58
# Comp:  2            [OI]6300_d     0.3257      0.41     -71    58
# Comp:  2           [NII]6583_d      4.058      0.41     -71    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -65        31
#  comp.  2:       -85        55
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.045      0.29     -65    31
# Comp:  1                Halpha      7.856      0.29     -65    31
# Comp:  2             [SII]6716      3.156      0.32     -85    55
# Comp:  2             [SII]6731      1.579      0.32     -85    55
# Comp:  2              HeII4687      0.000      0.32     -85    55
# Comp:  2               HeI5876     0.7680      0.32     -85    55
# Comp:  2          [OIII]5007_d      4.352      0.40     -85    55
# Comp:  2            [OI]6300_d     0.9839      0.40     -85    55
# Comp:  2           [NII]6583_d      3.657      0.40     -85    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        52
#  comp.  1:       -68        28
#  comp.  2:       -82        51
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.485      0.29     -68    28
# Comp:  1                Halpha      7.739      0.29     -68    28
# Comp:  2             [SII]6716      2.316      0.31     -82    51
# Comp:  2             [SII]6731      1.746      0.31     -82    51
# Comp:  2              HeII4687     0.6093      0.31     -82    51
# Comp:  2               HeI5876     0.1967      0.31     -82    51
# Comp:  2          [OIII]5007_d      3.252      0.40     -82    51
# Comp:  2            [OI]6300_d     0.8005      0.40     -82    51
# Comp:  2           [NII]6583_d      3.764      0.40     -82    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        69
#  comp.  1:       -69        37
#  comp.  2:       -87        57
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.021      0.30     -69    37
# Comp:  1                Halpha      8.112      0.30     -69    37
# Comp:  2             [SII]6716      3.055      0.32     -87    57
# Comp:  2             [SII]6731      1.671      0.32     -87    57
# Comp:  2              HeII4687      0.000      0.32     -87    57
# Comp:  2               HeI5876     0.4610      0.32     -87    57
# Comp:  2          [OIII]5007_d      3.428      0.40     -87    57
# Comp:  2            [OI]6300_d     0.5067      0.40     -87    57
# Comp:  2           [NII]6583_d      4.025      0.40     -87    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        14
#  comp.  1:       -69        31
#  comp.  2:       -85        59
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.091      0.29     -69    31
# Comp:  1                Halpha      7.717      0.29     -69    31
# Comp:  2             [SII]6716      2.659      0.32     -85    59
# Comp:  2             [SII]6731      1.669      0.32     -85    59
# Comp:  2              HeII4687      0.000      0.32     -85    59
# Comp:  2               HeI5876     0.3228      0.32     -85    59
# Comp:  2          [OIII]5007_d      4.558      0.41     -85    59
# Comp:  2            [OI]6300_d     0.7648      0.41     -85    59
# Comp:  2           [NII]6583_d      4.062      0.41     -85    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        55
#  comp.  1:       -72        26
#  comp.  2:       -84        34
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.965      0.29     -72    26
# Comp:  1                Halpha      8.115      0.29     -72    26
# Comp:  2             [SII]6716      2.063      0.30     -84    34
# Comp:  2             [SII]6731      1.596      0.30     -84    34
# Comp:  2              HeII4687      0.000      0.30     -84    34
# Comp:  2               HeI5876     0.4572      0.30     -84    34
# Comp:  2          [OIII]5007_d      3.224      0.37     -84    34
# Comp:  2            [OI]6300_d     0.7403      0.37     -84    34
# Comp:  2           [NII]6583_d      3.930      0.37     -84    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        55
#  comp.  1:       -70        41
#  comp.  2:       -87        48
# chi2/DOF: 1.199; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.285      0.30     -70    41
# Comp:  1                Halpha      8.438      0.30     -70    41
# Comp:  2             [SII]6716      2.981      0.31     -87    48
# Comp:  2             [SII]6731      1.629      0.31     -87    48
# Comp:  2              HeII4687      0.000      0.31     -87    48
# Comp:  2               HeI5876     0.4527      0.31     -87    48
# Comp:  2          [OIII]5007_d      3.698      0.39     -87    48
# Comp:  2            [OI]6300_d     0.8581      0.39     -87    48
# Comp:  2           [NII]6583_d      3.501      0.39     -87    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        71
#  comp.  1:       -71        35
#  comp.  2:       -89        57
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.157      0.30     -71    35
# Comp:  1                Halpha      8.029      0.30     -71    35
# Comp:  2             [SII]6716      2.572      0.32     -89    57
# Comp:  2             [SII]6731      1.596      0.32     -89    57
# Comp:  2              HeII4687     0.5615      0.32     -89    57
# Comp:  2               HeI5876     0.5032      0.32     -89    57
# Comp:  2          [OIII]5007_d      3.648      0.40     -89    57
# Comp:  2            [OI]6300_d      1.362      0.40     -89    57
# Comp:  2           [NII]6583_d      4.184      0.40     -89    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        45
#  comp.  1:       -70        30
#  comp.  2:       -77        21
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.888      0.29     -70    30
# Comp:  1                Halpha      7.808      0.29     -70    30
# Comp:  2             [SII]6716      2.370      0.29     -77    21
# Comp:  2             [SII]6731      1.516      0.29     -77    21
# Comp:  2              HeII4687     0.2739      0.29     -77    21
# Comp:  2               HeI5876     0.5297      0.29     -77    21
# Comp:  2          [OIII]5007_d      3.095      0.36     -77    21
# Comp:  2            [OI]6300_d     0.6686      0.36     -77    21
# Comp:  2           [NII]6583_d      3.374      0.36     -77    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -68        39
#  comp.  2:       -86        59
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.271      0.30     -68    39
# Comp:  1                Halpha      8.321      0.30     -68    39
# Comp:  2             [SII]6716      2.922      0.32     -86    59
# Comp:  2             [SII]6731      1.745      0.32     -86    59
# Comp:  2              HeII4687   0.008801      0.32     -86    59
# Comp:  2               HeI5876     0.4772      0.32     -86    59
# Comp:  2          [OIII]5007_d      4.279      0.41     -86    59
# Comp:  2            [OI]6300_d     0.7928      0.41     -86    59
# Comp:  2           [NII]6583_d      3.662      0.41     -86    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        54
#  comp.  1:       -71        36
#  comp.  2:       -84        38
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.376      0.30     -71    36
# Comp:  1                Halpha      8.121      0.30     -71    36
# Comp:  2             [SII]6716      2.736      0.30     -84    38
# Comp:  2             [SII]6731      1.439      0.30     -84    38
# Comp:  2              HeII4687     0.2811      0.30     -84    38
# Comp:  2               HeI5876     0.5648      0.30     -84    38
# Comp:  2          [OIII]5007_d      3.634      0.38     -84    38
# Comp:  2            [OI]6300_d     0.9179      0.38     -84    38
# Comp:  2           [NII]6583_d      4.019      0.38     -84    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        17
#  comp.  1:       -71        33
#  comp.  2:       -96        43
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.223      0.29     -71    33
# Comp:  1                Halpha      8.139      0.29     -71    33
# Comp:  2             [SII]6716      2.228      0.31     -96    43
# Comp:  2             [SII]6731      1.639      0.31     -96    43
# Comp:  2              HeII4687      0.000      0.31     -96    43
# Comp:  2               HeI5876     0.6701      0.31     -96    43
# Comp:  2          [OIII]5007_d      3.557      0.39     -96    43
# Comp:  2            [OI]6300_d     0.8641      0.39     -96    43
# Comp:  2           [NII]6583_d      3.748      0.39     -96    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        35
#  comp.  1:       -69        32
#  comp.  2:       -92        58
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.296      0.29     -69    32
# Comp:  1                Halpha      7.890      0.29     -69    32
# Comp:  2             [SII]6716      2.899      0.32     -92    58
# Comp:  2             [SII]6731      1.883      0.32     -92    58
# Comp:  2              HeII4687     0.4142      0.32     -92    58
# Comp:  2               HeI5876     0.5330      0.32     -92    58
# Comp:  2          [OIII]5007_d      3.942      0.41     -92    58
# Comp:  2            [OI]6300_d     0.5680      0.41     -92    58
# Comp:  2           [NII]6583_d      4.129      0.41     -92    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        39
#  comp.  1:       -70        30
#  comp.  2:       -92        47
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.564      0.29     -70    30
# Comp:  1                Halpha      7.720      0.29     -70    30
# Comp:  2             [SII]6716      2.825      0.31     -92    47
# Comp:  2             [SII]6731      1.948      0.31     -92    47
# Comp:  2              HeII4687    0.02646      0.31     -92    47
# Comp:  2               HeI5876     0.6260      0.31     -92    47
# Comp:  2          [OIII]5007_d      3.444      0.39     -92    47
# Comp:  2            [OI]6300_d     0.8310      0.39     -92    47
# Comp:  2           [NII]6583_d      3.700      0.39     -92    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        42
#  comp.  1:       -69        29
#  comp.  2:       -83        46
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.642      0.29     -69    29
# Comp:  1                Halpha      7.962      0.29     -69    29
# Comp:  2             [SII]6716      3.121      0.31     -83    46
# Comp:  2             [SII]6731      1.429      0.31     -83    46
# Comp:  2              HeII4687      0.000      0.31     -83    46
# Comp:  2               HeI5876     0.4354      0.31     -83    46
# Comp:  2          [OIII]5007_d      4.050      0.39     -83    46
# Comp:  2            [OI]6300_d     0.7527      0.39     -83    46
# Comp:  2           [NII]6583_d      4.043      0.39     -83    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        62
#  comp.  1:       -70        30
#  comp.  2:       -82        53
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.569      0.29     -70    30
# Comp:  1                Halpha      7.642      0.29     -70    30
# Comp:  2             [SII]6716      2.420      0.32     -82    53
# Comp:  2             [SII]6731      1.637      0.32     -82    53
# Comp:  2              HeII4687     0.6789      0.32     -82    53
# Comp:  2               HeI5876     0.5464      0.32     -82    53
# Comp:  2          [OIII]5007_d      4.413      0.40     -82    53
# Comp:  2            [OI]6300_d     0.6741      0.40     -82    53
# Comp:  2           [NII]6583_d      3.784      0.40     -82    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -69        31
#  comp.  2:       -83        44
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.692      0.29     -69    31
# Comp:  1                Halpha      8.232      0.29     -69    31
# Comp:  2             [SII]6716      2.653      0.31     -83    44
# Comp:  2             [SII]6731      1.674      0.31     -83    44
# Comp:  2              HeII4687    0.08670      0.31     -83    44
# Comp:  2               HeI5876     0.5865      0.31     -83    44
# Comp:  2          [OIII]5007_d      3.588      0.39     -83    44
# Comp:  2            [OI]6300_d     0.8794      0.39     -83    44
# Comp:  2           [NII]6583_d      4.041      0.39     -83    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        30
#  comp.  1:       -68        41
#  comp.  2:       -82        55
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.830      0.30     -68    41
# Comp:  1                Halpha      8.390      0.30     -68    41
# Comp:  2             [SII]6716      2.887      0.32     -82    55
# Comp:  2             [SII]6731      1.498      0.32     -82    55
# Comp:  2              HeII4687      0.000      0.32     -82    55
# Comp:  2               HeI5876     0.4665      0.32     -82    55
# Comp:  2          [OIII]5007_d      4.310      0.40     -82    55
# Comp:  2            [OI]6300_d     0.5558      0.40     -82    55
# Comp:  2           [NII]6583_d      3.996      0.40     -82    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        41
#  comp.  1:       -69        34
#  comp.  2:       -78        45
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.757      0.30     -69    34
# Comp:  1                Halpha      7.975      0.30     -69    34
# Comp:  2             [SII]6716      2.795      0.31     -78    45
# Comp:  2             [SII]6731      1.666      0.31     -78    45
# Comp:  2              HeII4687      0.000      0.31     -78    45
# Comp:  2               HeI5876     0.5094      0.31     -78    45
# Comp:  2          [OIII]5007_d      4.257      0.39     -78    45
# Comp:  2            [OI]6300_d      1.141      0.39     -78    45
# Comp:  2           [NII]6583_d      3.742      0.39     -78    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        70
#  comp.  1:       -67        34
#  comp.  2:       -87        57
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.668      0.30     -67    34
# Comp:  1                Halpha      8.108      0.30     -67    34
# Comp:  2             [SII]6716      2.510      0.32     -87    57
# Comp:  2             [SII]6731      2.060      0.32     -87    57
# Comp:  2              HeII4687      0.000      0.32     -87    57
# Comp:  2               HeI5876     0.2969      0.32     -87    57
# Comp:  2          [OIII]5007_d      3.363      0.41     -87    57
# Comp:  2            [OI]6300_d     0.8092      0.41     -87    57
# Comp:  2           [NII]6583_d      4.033      0.41     -87    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        44
#  comp.  1:       -70        29
#  comp.  2:       -81        47
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.688      0.29     -70    29
# Comp:  1                Halpha      7.979      0.29     -70    29
# Comp:  2             [SII]6716      2.457      0.31     -81    47
# Comp:  2             [SII]6731      1.709      0.31     -81    47
# Comp:  2              HeII4687     0.3536      0.31     -81    47
# Comp:  2               HeI5876     0.6345      0.31     -81    47
# Comp:  2          [OIII]5007_d      4.550      0.39     -81    47
# Comp:  2            [OI]6300_d      1.120      0.39     -81    47
# Comp:  2           [NII]6583_d      3.901      0.39     -81    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        57
#  comp.  1:       -68        33
#  comp.  2:       -82        69
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.119      0.29     -68    33
# Comp:  1                Halpha      8.040      0.29     -68    33
# Comp:  2             [SII]6716      3.262      0.34     -82    69
# Comp:  2             [SII]6731      1.721      0.34     -82    69
# Comp:  2              HeII4687      0.000      0.34     -82    69
# Comp:  2               HeI5876     0.4601      0.34     -82    69
# Comp:  2          [OIII]5007_d      4.356      0.42     -82    69
# Comp:  2            [OI]6300_d     0.7015      0.42     -82    69
# Comp:  2           [NII]6583_d      4.049      0.42     -82    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        46
#  comp.  1:       -70        33
#  comp.  2:       -79        51
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.828      0.29     -70    33
# Comp:  1                Halpha      7.919      0.29     -70    33
# Comp:  2             [SII]6716      3.008      0.31     -79    51
# Comp:  2             [SII]6731      1.652      0.31     -79    51
# Comp:  2              HeII4687      0.000      0.31     -79    51
# Comp:  2               HeI5876     0.2000      0.31     -79    51
# Comp:  2          [OIII]5007_d      4.092      0.40     -79    51
# Comp:  2            [OI]6300_d     0.7970      0.40     -79    51
# Comp:  2           [NII]6583_d      4.220      0.40     -79    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94        40
#  comp.  1:       -73        26
#  comp.  2:       -83        41
# chi2/DOF: 1.183; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.199      0.29     -73    26
# Comp:  1                Halpha      8.127      0.29     -73    26
# Comp:  2             [SII]6716      2.508      0.30     -83    41
# Comp:  2             [SII]6731      1.668      0.30     -83    41
# Comp:  2              HeII4687     0.1552      0.30     -83    41
# Comp:  2               HeI5876     0.3029      0.30     -83    41
# Comp:  2          [OIII]5007_d      4.067      0.38     -83    41
# Comp:  2            [OI]6300_d     0.8315      0.38     -83    41
# Comp:  2           [NII]6583_d      3.473      0.38     -83    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        39
#  comp.  1:       -69        32
#  comp.  2:       -87        56
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.847      0.29     -69    32
# Comp:  1                Halpha      8.000      0.29     -69    32
# Comp:  2             [SII]6716      3.164      0.32     -87    56
# Comp:  2             [SII]6731      1.833      0.32     -87    56
# Comp:  2              HeII4687     0.4483      0.32     -87    56
# Comp:  2               HeI5876     0.3271      0.32     -87    56
# Comp:  2          [OIII]5007_d      4.070      0.40     -87    56
# Comp:  2            [OI]6300_d     0.8895      0.40     -87    56
# Comp:  2           [NII]6583_d      4.168      0.40     -87    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -72        33
#  comp.  2:       -88        71
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.103      0.30     -72    33
# Comp:  1                Halpha      7.833      0.30     -72    33
# Comp:  2             [SII]6716      2.674      0.34     -88    71
# Comp:  2             [SII]6731      1.970      0.34     -88    71
# Comp:  2              HeII4687     0.3719      0.34     -88    71
# Comp:  2               HeI5876     0.6957      0.34     -88    71
# Comp:  2          [OIII]5007_d      4.755      0.43     -88    71
# Comp:  2            [OI]6300_d     0.9410      0.43     -88    71
# Comp:  2           [NII]6583_d      4.304      0.43     -88    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        45
#  comp.  1:       -71        30
#  comp.  2:       -86        46
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.265      0.29     -71    30
# Comp:  1                Halpha      7.999      0.29     -71    30
# Comp:  2             [SII]6716      2.684      0.31     -86    46
# Comp:  2             [SII]6731      1.397      0.31     -86    46
# Comp:  2              HeII4687     0.2371      0.31     -86    46
# Comp:  2               HeI5876     0.5502      0.31     -86    46
# Comp:  2          [OIII]5007_d      3.812      0.39     -86    46
# Comp:  2            [OI]6300_d     0.7976      0.39     -86    46
# Comp:  2           [NII]6583_d      3.791      0.39     -86    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        61
#  comp.  1:       -70        26
#  comp.  2:       -87        40
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.590      0.29     -70    26
# Comp:  1                Halpha      7.731      0.29     -70    26
# Comp:  2             [SII]6716      2.405      0.30     -87    40
# Comp:  2             [SII]6731      1.748      0.30     -87    40
# Comp:  2              HeII4687      0.000      0.30     -87    40
# Comp:  2               HeI5876     0.2067      0.30     -87    40
# Comp:  2          [OIII]5007_d      3.726      0.38     -87    40
# Comp:  2            [OI]6300_d     0.8645      0.38     -87    40
# Comp:  2           [NII]6583_d      3.694      0.38     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        93
#  comp.  1:       -69        32
#  comp.  2:       -84        51
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.432      0.29     -69    32
# Comp:  1                Halpha      7.629      0.29     -69    32
# Comp:  2             [SII]6716      2.221      0.31     -84    51
# Comp:  2             [SII]6731      1.844      0.31     -84    51
# Comp:  2              HeII4687      0.000      0.31     -84    51
# Comp:  2               HeI5876     0.5550      0.31     -84    51
# Comp:  2          [OIII]5007_d      3.216      0.40     -84    51
# Comp:  2            [OI]6300_d     0.8732      0.40     -84    51
# Comp:  2           [NII]6583_d      4.073      0.40     -84    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29       102
#  comp.  1:       -66        38
#  comp.  2:       -79        59
# chi2/DOF: 1.187; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.669      0.30     -66    38
# Comp:  1                Halpha      8.421      0.30     -66    38
# Comp:  2             [SII]6716      2.886      0.32     -79    59
# Comp:  2             [SII]6731      1.923      0.32     -79    59
# Comp:  2              HeII4687     0.2033      0.32     -79    59
# Comp:  2               HeI5876     0.5326      0.32     -79    59
# Comp:  2          [OIII]5007_d      4.174      0.41     -79    59
# Comp:  2            [OI]6300_d     0.7682      0.41     -79    59
# Comp:  2           [NII]6583_d      4.008      0.41     -79    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        65
#  comp.  1:       -69        34
#  comp.  2:       -93        59
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.792      0.30     -69    34
# Comp:  1                Halpha      7.840      0.30     -69    34
# Comp:  2             [SII]6716      2.993      0.32     -93    59
# Comp:  2             [SII]6731      1.908      0.32     -93    59
# Comp:  2              HeII4687   0.003283      0.32     -93    59
# Comp:  2               HeI5876     0.3652      0.32     -93    59
# Comp:  2          [OIII]5007_d      4.084      0.41     -93    59
# Comp:  2            [OI]6300_d     0.4996      0.41     -93    59
# Comp:  2           [NII]6583_d      3.936      0.41     -93    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        69
#  comp.  1:       -69        30
#  comp.  2:       -76        41
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.625      0.29     -69    30
# Comp:  1                Halpha      7.979      0.29     -69    30
# Comp:  2             [SII]6716      2.216      0.30     -76    41
# Comp:  2             [SII]6731      1.683      0.30     -76    41
# Comp:  2              HeII4687      0.000      0.30     -76    41
# Comp:  2               HeI5876     0.4970      0.30     -76    41
# Comp:  2          [OIII]5007_d      3.862      0.38     -76    41
# Comp:  2            [OI]6300_d     0.7884      0.38     -76    41
# Comp:  2           [NII]6583_d      3.782      0.38     -76    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        55
#  comp.  1:       -70        28
#  comp.  2:       -83        37
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.811      0.29     -70    28
# Comp:  1                Halpha      7.777      0.29     -70    28
# Comp:  2             [SII]6716      2.303      0.30     -83    37
# Comp:  2             [SII]6731      1.387      0.30     -83    37
# Comp:  2              HeII4687      0.000      0.30     -83    37
# Comp:  2               HeI5876     0.3143      0.30     -83    37
# Comp:  2          [OIII]5007_d      3.736      0.38     -83    37
# Comp:  2            [OI]6300_d     0.7846      0.38     -83    37
# Comp:  2           [NII]6583_d      3.547      0.38     -83    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        62
#  comp.  1:       -67        35
#  comp.  2:       -87        43
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.691      0.30     -67    35
# Comp:  1                Halpha      8.226      0.30     -67    35
# Comp:  2             [SII]6716      2.905      0.30     -87    43
# Comp:  2             [SII]6731      1.636      0.30     -87    43
# Comp:  2              HeII4687      0.000      0.30     -87    43
# Comp:  2               HeI5876     0.4615      0.30     -87    43
# Comp:  2          [OIII]5007_d      3.761      0.39     -87    43
# Comp:  2            [OI]6300_d     0.6176      0.39     -87    43
# Comp:  2           [NII]6583_d      3.531      0.39     -87    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        42
#  comp.  1:       -68        36
#  comp.  2:       -90        65
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.309      0.30     -68    36
# Comp:  1                Halpha      7.994      0.30     -68    36
# Comp:  2             [SII]6716      3.075      0.33     -90    65
# Comp:  2             [SII]6731      1.682      0.33     -90    65
# Comp:  2              HeII4687      0.000      0.33     -90    65
# Comp:  2               HeI5876     0.6374      0.33     -90    65
# Comp:  2          [OIII]5007_d      4.483      0.42     -90    65
# Comp:  2            [OI]6300_d      1.007      0.42     -90    65
# Comp:  2           [NII]6583_d      3.864      0.42     -90    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -67        39
#  comp.  2:       -78        50
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.491      0.30     -67    39
# Comp:  1                Halpha      8.582      0.30     -67    39
# Comp:  2             [SII]6716      3.052      0.31     -78    50
# Comp:  2             [SII]6731      2.044      0.31     -78    50
# Comp:  2              HeII4687     0.4417      0.31     -78    50
# Comp:  2               HeI5876     0.5541      0.31     -78    50
# Comp:  2          [OIII]5007_d      3.828      0.39     -78    50
# Comp:  2            [OI]6300_d      1.110      0.39     -78    50
# Comp:  2           [NII]6583_d      4.032      0.39     -78    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        66
#  comp.  1:       -70        38
#  comp.  2:       -85        35
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.241      0.30     -70    38
# Comp:  1                Halpha      8.216      0.30     -70    38
# Comp:  2             [SII]6716      2.493      0.30     -85    35
# Comp:  2             [SII]6731      1.498      0.30     -85    35
# Comp:  2              HeII4687     0.4338      0.30     -85    35
# Comp:  2               HeI5876     0.2035      0.30     -85    35
# Comp:  2          [OIII]5007_d      3.765      0.38     -85    35
# Comp:  2            [OI]6300_d     0.6691      0.38     -85    35
# Comp:  2           [NII]6583_d      3.767      0.38     -85    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        65
#  comp.  1:       -68        33
#  comp.  2:       -76        48
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.321      0.30     -68    33
# Comp:  1                Halpha      7.841      0.30     -68    33
# Comp:  2             [SII]6716      2.727      0.31     -76    48
# Comp:  2             [SII]6731      1.729      0.31     -76    48
# Comp:  2              HeII4687     0.2891      0.31     -76    48
# Comp:  2               HeI5876     0.4027      0.31     -76    48
# Comp:  2          [OIII]5007_d      4.015      0.39     -76    48
# Comp:  2            [OI]6300_d      1.076      0.39     -76    48
# Comp:  2           [NII]6583_d      3.651      0.39     -76    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        86
#  comp.  1:       -69        40
#  comp.  2:       -80        48
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.857      0.30     -69    40
# Comp:  1                Halpha      8.308      0.30     -69    40
# Comp:  2             [SII]6716      3.009      0.31     -80    48
# Comp:  2             [SII]6731      1.515      0.31     -80    48
# Comp:  2              HeII4687      0.000      0.31     -80    48
# Comp:  2               HeI5876     0.3356      0.31     -80    48
# Comp:  2          [OIII]5007_d      3.752      0.39     -80    48
# Comp:  2            [OI]6300_d     0.6684      0.39     -80    48
# Comp:  2           [NII]6583_d      3.625      0.39     -80    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        24
#  comp.  1:       -72        43
#  comp.  2:       -92        56
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.244      0.30     -72    43
# Comp:  1                Halpha      8.218      0.30     -72    43
# Comp:  2             [SII]6716      2.836      0.32     -92    56
# Comp:  2             [SII]6731      1.609      0.32     -92    56
# Comp:  2              HeII4687      0.000      0.32     -92    56
# Comp:  2               HeI5876     0.5817      0.32     -92    56
# Comp:  2          [OIII]5007_d      4.094      0.40     -92    56
# Comp:  2            [OI]6300_d     0.6735      0.40     -92    56
# Comp:  2           [NII]6583_d      3.733      0.40     -92    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -67        32
#  comp.  2:       -83        43
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.839      0.29     -67    32
# Comp:  1                Halpha      8.078      0.29     -67    32
# Comp:  2             [SII]6716      2.511      0.30     -83    43
# Comp:  2             [SII]6731      1.669      0.30     -83    43
# Comp:  2              HeII4687     0.3208      0.30     -83    43
# Comp:  2               HeI5876     0.6699      0.30     -83    43
# Comp:  2          [OIII]5007_d      3.266      0.38     -83    43
# Comp:  2            [OI]6300_d     0.7025      0.38     -83    43
# Comp:  2           [NII]6583_d      3.606      0.38     -83    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        19
#  comp.  1:       -74        27
#  comp.  2:       -85        57
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.237      0.29     -74    27
# Comp:  1                Halpha      8.024      0.29     -74    27
# Comp:  2             [SII]6716      2.378      0.32     -85    57
# Comp:  2             [SII]6731      1.788      0.32     -85    57
# Comp:  2              HeII4687      0.000      0.32     -85    57
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.931      0.31     -70    46
# Comp:  1                Halpha      8.330      0.31     -70    46
# Comp:  2             [SII]6716      3.047      0.33     -73    63
# Comp:  2             [SII]6731      2.019      0.33     -73    63
# Comp:  2              HeII4687      0.000      0.33     -73    63
# Comp:  2               HeI5876     0.5869      0.33     -73    63
# Comp:  2          [OIII]5007_d      4.354      0.41     -73    63
# Comp:  2            [OI]6300_d     0.8852      0.41     -73    63
# Comp:  2           [NII]6583_d      3.841      0.41     -73    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        29
#  comp.  1:       -71        41
#  comp.  2:       -85        51
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.699      0.30     -71    41
# Comp:  1                Halpha      8.391      0.30     -71    41
# Comp:  2             [SII]6716      2.649      0.31     -85    51
# Comp:  2             [SII]6731      1.623      0.31     -85    51
# Comp:  2              HeII4687      0.000      0.31     -85    51
# Comp:  2               HeI5876     0.5637      0.31     -85    51
# Comp:  2          [OIII]5007_d      4.078      0.40     -85    51
# Comp:  2            [OI]6300_d     0.9778      0.40     -85    51
# Comp:  2           [NII]6583_d      3.924      0.40     -85    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        73
#  comp.  1:       -65        35
#  comp.  2:       -80        46
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.921      0.30     -65    35
# Comp:  1                Halpha      8.107      0.30     -65    35
# Comp:  2             [SII]6716      2.518      0.31     -80    46
# Comp:  2             [SII]6731      1.637      0.31     -80    46
# Comp:  2              HeII4687      0.000      0.31     -80    46
# Comp:  2               HeI5876     0.5195      0.31     -80    46
# Comp:  2          [OIII]5007_d      3.789      0.39     -80    46
# Comp:  2            [OI]6300_d     0.8793      0.39     -80    46
# Comp:  2           [NII]6583_d      4.138      0.39     -80    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        48
#  comp.  1:       -71        38
#  comp.  2:       -90        40
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.260      0.30     -71    38
# Comp:  1                Halpha      8.197      0.30     -71    38
# Comp:  2             [SII]6716      2.613      0.30     -90    40
# Comp:  2             [SII]6731      1.659      0.30     -90    40
# Comp:  2              HeII4687     0.4983      0.30     -90    40
# Comp:  2               HeI5876     0.3715      0.30     -90    40
# Comp:  2          [OIII]5007_d      2.985      0.38     -90    40
# Comp:  2            [OI]6300_d     0.8182      0.38     -90    40
# Comp:  2           [NII]6583_d      3.933      0.38     -90    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        59
#  comp.  1:       -73        28
#  comp.  2:       -95        53
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.869      0.29     -73    28
# Comp:  1                Halpha      7.722      0.29     -73    28
# Comp:  2             [SII]6716      2.855      0.32     -95    53
# Comp:  2             [SII]6731      1.752      0.32     -95    53
# Comp:  2              HeII4687      0.000      0.32     -95    53
# Comp:  2               HeI5876     0.2218      0.32     -95    53
# Comp:  2          [OIII]5007_d      3.968      0.40     -95    53
# Comp:  2            [OI]6300_d     0.7789      0.40     -95    53
# Comp:  2           [NII]6583_d      3.848      0.40     -95    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        48
#  comp.  1:       -71        28
#  comp.  2:       -87        56
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.255      0.29     -71    28
# Comp:  1                Halpha      7.942      0.29     -71    28
# Comp:  2             [SII]6716      2.982      0.32     -87    56
# Comp:  2             [SII]6731      1.844      0.32     -87    56
# Comp:  2              HeII4687     0.1317      0.32     -87    56
# Comp:  2               HeI5876     0.5716      0.32     -87    56
# Comp:  2          [OIII]5007_d      3.520      0.40     -87    56
# Comp:  2            [OI]6300_d     0.5453      0.40     -87    56
# Comp:  2           [NII]6583_d      4.003      0.40     -87    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        51
#  comp.  1:       -67        37
#  comp.  2:       -74        61
# chi2/DOF: 1.199; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.217      0.30     -67    37
# Comp:  1                Halpha      8.221      0.30     -67    37
# Comp:  2             [SII]6716      2.514      0.33     -74    61
# Comp:  2             [SII]6731      1.754      0.33     -74    61
# Comp:  2              HeII4687     0.2308      0.33     -74    61
# Comp:  2               HeI5876     0.3253      0.33     -74    61
# Comp:  2          [OIII]5007_d      3.991      0.41     -74    61
# Comp:  2            [OI]6300_d     0.8073      0.41     -74    61
# Comp:  2           [NII]6583_d      4.316      0.41     -74    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        29
#  comp.  1:       -67        34
#  comp.  2:       -89        61
# chi2/DOF: 1.191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.572      0.30     -67    34
# Comp:  1                Halpha      8.252      0.30     -67    34
# Comp:  2             [SII]6716      3.232      0.33     -89    61
# Comp:  2             [SII]6731      1.703      0.33     -89    61
# Comp:  2              HeII4687     0.3467      0.33     -89    61
# Comp:  2               HeI5876     0.8215      0.33     -89    61
# Comp:  2          [OIII]5007_d      3.791      0.41     -89    61
# Comp:  2            [OI]6300_d     0.7700      0.41     -89    61
# Comp:  2           [NII]6583_d      4.061      0.41     -89    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        32
#  comp.  1:       -71        29
#  comp.  2:       -94        52
# chi2/DOF: 1.190; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.981      0.29     -71    29
# Comp:  1                Halpha      7.699      0.29     -71    29
# Comp:  2             [SII]6716      2.629      0.31     -94    52
# Comp:  2             [SII]6731      1.792      0.31     -94    52
# Comp:  2              HeII4687      0.000      0.31     -94    52
# Comp:  2               HeI5876     0.4784      0.31     -94    52
# Comp:  2          [OIII]5007_d      3.793      0.40     -94    52
# Comp:  2            [OI]6300_d     0.6814      0.40     -94    52
# Comp:  2           [NII]6583_d      3.752      0.40     -94    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        30
#  comp.  1:       -68        34
#  comp.  2:       -82        50
# chi2/DOF: 1.197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.789      0.30     -68    34
# Comp:  1                Halpha      7.906      0.30     -68    34
# Comp:  2             [SII]6716      2.550      0.31     -82    50
# Comp:  2             [SII]6731      1.564      0.31     -82    50
# Comp:  2              HeII4687      0.000      0.31     -82    50
# Comp:  2               HeI5876     0.1951      0.31     -82    50
# Comp:  2          [OIII]5007_d      3.900      0.39     -82    50
# Comp:  2            [OI]6300_d     0.6859      0.39     -82    50
# Comp:  2           [NII]6583_d      4.003      0.39     -82    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -70        37
#  comp.  2:       -77        49
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.111      0.30     -70    37
# Comp:  1                Halpha      7.888      0.30     -70    37
# Comp:  2             [SII]6716      2.773      0.31     -77    49
# Comp:  2             [SII]6731      1.674      0.31     -77    49
# Comp:  2              HeII4687      0.000      0.31     -77    49
# Comp:  2               HeI5876     0.2994      0.31     -77    49
# Comp:  2          [OIII]5007_d      3.486      0.39     -77    49
# Comp:  2            [OI]6300_d     0.7193      0.39     -77    49
# Comp:  2           [NII]6583_d      4.250      0.39     -77    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        46
#  comp.  1:       -75        32
#  comp.  2:       -84        38
# chi2/DOF: 1.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.245      0.29     -75    32
# Comp:  1                Halpha      7.806      0.29     -75    32
# Comp:  2             [SII]6716      2.314      0.30     -84    38
# Comp:  2             [SII]6731      1.603      0.30     -84    38
# Comp:  2              HeII4687      0.000      0.30     -84    38
# Comp:  2               HeI5876     0.2462      0.30     -84    38
# Comp:  2          [OIII]5007_d      3.599      0.38     -84    38
# Comp:  2            [OI]6300_d     0.8116      0.38     -84    38
# Comp:  2           [NII]6583_d      3.546      0.38     -84    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        58
#  comp.  1:       -69        33
#  comp.  2:       -97        59
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.100      0.29     -69    33
# Comp:  1                Halpha      8.070      0.29     -69    33
# Comp:  2             [SII]6716      2.344      0.32     -97    59
# Comp:  2             [SII]6731      1.859      0.32     -97    59
# Comp:  2              HeII4687     0.3235      0.32     -97    59
# Comp:  2               HeI5876     0.2701      0.32     -97    59
# Comp:  2          [OIII]5007_d      3.771      0.41     -97    59
# Comp:  2            [OI]6300_d      1.172      0.41     -97    59
# Comp:  2           [NII]6583_d      3.731      0.41     -97    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        31
#  comp.  1:       -66        44
#  comp.  2:       -82        46
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.637      0.31     -66    44
# Comp:  1                Halpha      8.439      0.31     -66    44
# Comp:  2             [SII]6716      2.924      0.31     -82    46
# Comp:  2             [SII]6731      1.674      0.31     -82    46
# Comp:  2              HeII4687     0.3011      0.31     -82    46
# Comp:  2               HeI5876     0.5550      0.31     -82    46
# Comp:  2          [OIII]5007_d      3.502      0.39     -82    46
# Comp:  2            [OI]6300_d      1.021      0.39     -82    46
# Comp:  2           [NII]6583_d      3.845      0.39     -82    46
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.35474094, 0.34904294, 0.38332695, 0.2064202 , 0.17154588,
#        0.17308668, 0.42117927, 0.26397675, 0.31492955])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.87530412, 10.88788632,  3.69204988,  2.35304292,  0.        ,
#         0.5048648 ,  3.92937419,  1.04687813,  5.27275732])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_8_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_8", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_8_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_8_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_8_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.109610    0.010034
# 1        Halpha  0.307956    0.009872
# 2     [SII]6716  0.104427    0.010842
# 3     [SII]6731  0.066554    0.005838
# 4      HeII4687  0.000000    0.004852
# 5       HeI5876  0.014280    0.004896
# 6  [OIII]5007_d  0.111140    0.011913
# 7    [OI]6300_d  0.029610    0.007466
# 8   [NII]6583_d  0.149136    0.008908
#           Name      Flux  Error_flux
# 0        Hbeta  0.109610    0.010034
# 1       Halpha  0.307956    0.009872
# 2    [SII]6716  0.104427    0.010842
# 3    [SII]6731  0.066554    0.005838
# 4     HeII4687  0.000000    0.004852
# 5      HeI5876  0.014280    0.004896
# 6   [OIII]4959  0.027785    0.011913
# 7   [OIII]5007  0.083355    0.011913
# 8     [OI]6300  0.022208    0.007466
# 9     [OI]6364  0.007403    0.007466
# 10   [NII]6548  0.037284    0.008908
# 11   [NII]6583  0.111852    0.008908

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0282843060696339
