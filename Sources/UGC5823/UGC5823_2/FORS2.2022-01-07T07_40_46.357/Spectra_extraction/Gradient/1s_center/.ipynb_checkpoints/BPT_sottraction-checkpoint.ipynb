# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
spectra_c = []
spectra_dx = []
spectra_sx = []

for i in range(1, 8):
    df = pd.read_csv(f"Spectrum_center_{i}_gas_exp.csv")
    spectra_c.append(df)

for i in range(1, 8):
    df = pd.read_csv(f"Spectrum_dx_{i}_gas_exp.csv")
    spectra_dx.append(df)

for i in range(1, 8):
    df = pd.read_csv(f"Spectrum_sx_{i}_gas_exp.csv")
    spectra_sx.append(df)

# %%
spectra_c[3]
# Out:
#           Name      Flux  Error_flux
# 0        Hbeta  0.403027    0.041562
# 1       Halpha  1.538281    0.021821
# 2    [SII]6716  0.348733    0.009205
# 3    [SII]6731  0.244092    0.009246
# 4     HeII4687  0.000000    0.005396
# 5      HeI5876  0.041014    0.002851
# 6   [OIII]4959  0.089554    0.012974
# 7   [OIII]5007  0.268661    0.012974
# 8     [OI]6300  0.049853    0.007249
# 9     [OI]6364  0.016618    0.007249
# 10   [NII]6548  0.131896    0.012350
# 11   [NII]6583  0.395687    0.012350

# %%
spectra_sx[3]
# Out:
#           Name      Flux  Error_flux
# 0        Hbeta  1.239706    0.117830
# 1       Halpha  4.383474    0.054776
# 2    [SII]6716  0.778327    0.030893
# 3    [SII]6731  0.520409    0.021348
# 4     HeII4687  0.000000    0.006208
# 5      HeI5876  0.156504    0.015193
# 6   [OIII]4959  0.454728    0.070915
# 7   [OIII]5007  1.364184    0.070915
# 8     [OI]6300  0.085767    0.008000
# 9     [OI]6364  0.028589    0.008000
# 10   [NII]6548  0.328957    0.032768
# 11   [NII]6583  0.986871    0.032768

# %%
spectra_dx[3]
# Out:
#           Name      Flux  Error_flux
# 0        Hbeta  0.369469    0.033375
# 1       Halpha  1.071771    0.016248
# 2    [SII]6716  0.280213    0.008299
# 3    [SII]6731  0.203916    0.004379
# 4     HeII4687  0.006592    0.004523
# 5      HeI5876  0.037809    0.002892
# 6   [OIII]4959  0.063127    0.009847
# 7   [OIII]5007  0.189382    0.009847
# 8     [OI]6300  0.057543    0.006658
# 9     [OI]6364  0.019181    0.006658
# 10   [NII]6548  0.102204    0.010137
# 11   [NII]6583  0.306612    0.010137

# %%
def Ku03(x):
    # AGN selection based on Kauffman et al. 2003
    # log OIII/Hb > 0.61/(log NII/Ha - 0.05) + 1.3
    return 0.61/(x - 0.05) + 1.3

def Ke01(x):
     # AGN selection based on Kewley et al. 2001
     # log OIII/Hb > 0.61/(log NII/Ha - 0.47) + 1.19
     return 0.61/(x - 0.47) + 1.19

def S06(x):
    # AGN selection based on Stasinska et al 2006
     # log OIII/Hb > 0.29/(log NII/Ha +0.20) + 0.96
    return 0.29/(x + 0.20) + 0.96

def C10(x):
 # Seyfert–LINER line based on Cid Fernandes et al 2010
    return 1.01*x + 0.48

def Ke01_SII(x):
     # AGN selection based on Kewley et al. 2001
     # log OIII/Hb > 0.72/(log SII/Ha - 0.32) + 1.3
     return 0.72/(x - 0.32) + 1.3

def Ke06(x):
    #Seyfert–LINER line
    return 1.89* x + 0.76

def real_flux(spectrum_sx, spectrum_c, spectrum_dx):
    flux_sx = spectrum_sx['Flux']
    flux_c = spectrum_c['Flux']
    flux_dx = spectrum_dx['Flux']
    err_flux_sx = spectrum_sx['Error_flux']
    err_flux_c = spectrum_c['Error_flux']
    err_flux_dx = spectrum_dx['Error_flux']
    num = [0, 1, 2, 7, 11]
    real_err = []
    real_flux = []
    for i in num:
        mean = np.mean([flux_sx[i], flux_dx[i]])
        diff = flux_c[i] - mean
        if diff >= 0:
            real_flux.append(diff)

            real_err.append(np.sqrt(err_flux_c[i]**2 + (err_flux_sx[i]/2)**2 + (err_flux_dx[i]/2)**2))

        else:
            real_flux.append(np.nan)
            real_err.append(np.nan)
        
    return np.array(real_flux), np.array(real_err)

def one_diff_flux(spectrum_l, spectrum_c):
    flux_l = spectrum_l['Flux']
    flux_c = spectrum_c['Flux']
    err_flux_l = spectrum_l['Error_flux']
    err_flux_c = spectrum_c['Error_flux']
    
    num = [0, 1, 2, 7, 11]
    real_err = []
    real_flux = []
    for i in num:
        diff = flux_c[i] - flux_l[i]
        if diff >= 0:
            real_flux.append(diff)

            real_err.append(np.sqrt(err_flux_c[i]**2 + (err_flux_l[i])**2))
        else:
            real_flux.append(np.nan)
            real_err.append(np.nan)
        
    return np.array(real_flux), np.array(real_err)
    
def error_ratio(err_1, err_2, flux_1, flux_2):
    try:
        e_1 = err_1 / (flux_1 * np.log(10)) if flux_1 != 0 else np.nan
        e_2 = err_2 / (flux_2 * np.log(10)) if flux_2 != 0 else np.nan
        return np.sqrt(e_1**2 + e_2**2)
    except:
        return np.nan

def ratio(flux, err_flux):

    HB   = flux[0]
    HA   = flux[1]
    SII  = flux[2]
    OIII = flux[3]
    NII  = flux[4]
   
    OIII_HB = np.log10(OIII / HB) #if OIII > 0 and HB > 0 #else np.nan
    NII_HA  = np.log10(NII / HA) # if NII >  0 and HA > 0 #else np.nan
    SII_HA  = np.log10(SII / HA) # if SII > 0 and HA > 0 #else np.nan
    print('log ratio OIII_HB: ', OIII_HB)
    print('log ratio NII_HA: ', NII_HA)
    print('log ratio SII_HA: ', SII_HA)
    if np.isnan(OIII_HB) == False:
        err_OIII_HB = error_ratio(err_flux[3], err_flux[0], OIII, HB)
        print('err OIII/HB:', err_OIII_HB)
    else: err_OIII_HB = np.nan
        
    if np.isnan(NII_HA) == False:
        err_NII_HA  = error_ratio(err_flux[4], err_flux[1], NII, HA) 
        print('err NII/HA:', err_NII_HA)
    else: err_NII_HA = np.nan
        
    if np.isnan(SII_HA) == False:
        err_SII_HA  = error_ratio(err_flux[2], err_flux[1], SII, HA)
        print('err SII/HA:', err_SII_HA)
    else: err_SII_HA = np.nan
    return OIII_HB, NII_HA, SII_HA, err_OIII_HB, err_NII_HA, err_SII_HA

def ratio_c(flux, err_flux):
    HB   = flux[0]
    HA   = flux[1]
    SII  = flux[2]
    OIII = flux[7]
    NII  = flux[11]
   
    OIII_HB = np.log10(OIII / HB) #if OIII > 0 and HB > 0 #else np.nan
    NII_HA  = np.log10(NII / HA) # if NII >  0 and HA > 0 #else np.nan
    SII_HA  = np.log10(SII / HA) # if SII > 0 and HA > 0 #else np.nan
    print('log ratio OIII_HB_c: ', OIII_HB)
    print('log ratio NII_HA_c: ', NII_HA)
    print('log ratio SII_HA_c: ', SII_HA)

    err_OIII_HB = error_ratio(err_flux[7], err_flux[0], OIII, HB)
    err_NII_HA  = error_ratio(err_flux[11], err_flux[1], NII, HA)
    err_SII_HA  = error_ratio(err_flux[2], err_flux[1], SII, HA)

    return OIII_HB, NII_HA, SII_HA, err_OIII_HB, err_NII_HA, err_SII_HA

# %%
NII_HA = np.zeros(len(spectra_c))
OIII_HB = np.zeros(len(spectra_c))
SII_HA = np.zeros(len(spectra_c))
err_OIII_HB = np.zeros(len(spectra_c))
err_NII_HA = np.zeros(len(spectra_c))
err_SII_HA = np.zeros(len(spectra_c))
NII_HA_c = np.zeros(len(spectra_c))
OIII_HB_c = np.zeros(len(spectra_c))
SII_HA_c = np.zeros(len(spectra_c))
err_OIII_HB_c = np.zeros(len(spectra_c))
err_NII_HA_c = np.zeros(len(spectra_c))
err_SII_HA_c = np.zeros(len(spectra_c))

fig, ax = plt.subplots(1, 2, figsize=(12, 5), sharey = True)
fig.suptitle('BPT subtraction 1s')
colors = ['blue', 'green', 'magenta', 'orange', 'chocolate', 'dodgerblue', 'deeppink']
num_both = [0, 1, 2, 4, 6]#, 3]
num_single = [1, 3]
for i in num_both:
    print(i)
    diff_flux, diff_err = real_flux(spectra_sx[i], spectra_c[i], spectra_dx[i])
    OIII_HB[i], NII_HA[i], SII_HA[i], err_OIII_HB[i], err_NII_HA[i], err_SII_HA[i] = ratio(diff_flux, diff_err)
    OIII_HB_c[i], NII_HA_c[i], SII_HA_c[i], err_OIII_HB_c[i], err_NII_HA_c[i], err_SII_HA_c[i] = ratio_c(spectra_c[i]['Flux'], spectra_c[i]['Error_flux'])
    
    #ax[0].errorbar(x = np.log10(NII_HA[i]), y = np.log10(OIII_HB[i]), xerr = err_NII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
    #markersize = 4, marker = 'o')
    #ax[1].errorbar(x = np.log10(SII_HA[i]), y = np.log10(OIII_HB[i]), xerr = err_SII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
    #markersize = 4, marker = 'o')
print(3)
diff_flux, diff_err = one_diff_flux(spectra_dx[3], spectra_c[3])
OIII_HB[3], NII_HA[3], SII_HA[3], err_OIII_HB[3], err_NII_HA[3], err_SII_HA[3] = ratio(diff_flux, diff_err)
OIII_HB_c[3], NII_HA_c[3], SII_HA_c[3], err_OIII_HB_c[3], err_NII_HA_c[3], err_SII_HA_c[3] = ratio_c(spectra_c[3]['Flux'], spectra_c[3]['Error_flux'])
print(5)
diff_flux, diff_err = one_diff_flux(spectra_sx[5], spectra_c[5])
OIII_HB[5], NII_HA[5], SII_HA[5], err_OIII_HB[5], err_NII_HA[5], err_SII_HA[5] = ratio(diff_flux, diff_err)
OIII_HB_c[5], NII_HA_c[5], SII_HA_c[5], err_OIII_HB_c[5], err_NII_HA_c[5], err_SII_HA_c[5] = ratio_c(spectra_c[5]['Flux'], spectra_c[5]['Error_flux'])

for i in range(7):
    ax[0].errorbar(x = NII_HA[i], y = OIII_HB[i], xerr = err_NII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
               markersize = 4, marker = 'o')
    ax[1].errorbar(x = SII_HA[i], y = OIII_HB[i], xerr = err_SII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
              markersize = 4, marker = 'o')
    ax[0].errorbar(x = NII_HA_c[i], y = OIII_HB_c[i], xerr = err_NII_HA_c[i], yerr = err_OIII_HB_c[i], color = colors[i], 
               markersize = 4, marker = 'o', alpha = 0.4)
    ax[1].errorbar(x = SII_HA_c[i], y = OIII_HB_c[i], xerr = err_SII_HA_c[i], yerr = err_OIII_HB_c[i], color = colors[i], 
              markersize = 4, marker = 'o', alpha = 0.4)

x = np.linspace(-2, 0.04, num=200)
x1 = np.linspace(-2, 0.457, num=200)
x2 = np.linspace(-2, -0.25, num=200)
x3 = np.linspace(-0.49, 5, num=200)
ax[0].plot(x, Ku03(x), label = 'K03')
ax[0].plot(x1, Ke01(x1), label = 'K01')
ax[0].plot(x2, S06(x2), label = 'S06')

ax[0].plot(x3, C10(x3), label = 'C10')    
ax[0].set_xlim(-2, 1)
ax[0].set_ylim(-1.5, 2)
ax[0].set_xlabel('log([NII]λ6583/Hα)', fontsize=12)
ax[0].set_ylabel('log([OIII]λ5007/Hβ)', fontsize=12)
ax[0].legend()

x = np.linspace(-2, 0.1, num=200)
x1 = np.linspace(-0.31, 1, num=200)
ax[1].plot(x, Ke01_SII(x), label = 'Ke01_SII')
ax[1].plot(x1, Ke06(x1), label = 'Ke06')

ax[1].set_xlim(-2, 1)
ax[1].set_ylim(-1.5, 2)
ax[1].set_xlabel('log([SII]λ6583/Hα)', fontsize=12)
ax[1].legend()

plt.subplots_adjust(wspace=0.07)
plt.savefig('BPT_diff_1s_motion.png', bbox_inches='tight')
# Out:
# 0
# log ratio OIII_HB:  0.1925209886846355
# log ratio NII_HA:  -0.6973981390536969
# log ratio SII_HA:  -0.6252448470430092
# err OIII/HB: 0.12850238339032813
# err NII/HA: 0.055302092599221225
# err SII/HA: 0.030794519782809084
# log ratio OIII_HB_c:  0.18382444179581878
# log ratio NII_HA_c:  -0.6903830351424834
# log ratio SII_HA_c:  -0.6321218131903606
# 1
# log ratio OIII_HB:  0.019637098744066522
# log ratio NII_HA:  -0.6965542595269643
# log ratio SII_HA:  -0.9294402424082912
# err OIII/HB: 0.07442779772868466
# err NII/HA: 0.018082872012280572
# err SII/HA: 0.01667049623372555
# log ratio OIII_HB_c:  -0.01145548063919008
# log ratio NII_HA_c:  -0.6913453973399051
# log ratio SII_HA_c:  -0.8965411867460278
# 2
# log ratio OIII_HB:  0.09304984707265483
# log ratio NII_HA:  -0.6760645285980194
# log ratio SII_HA:  -0.9325637366199888
# err OIII/HB: 0.09239932876924893
# err NII/HA: 0.019908940152760644
# err SII/HA: 0.027325531479808186
# log ratio OIII_HB_c:  0.04232353635868924
# log ratio NII_HA_c:  -0.6611835903566468
# log ratio SII_HA_c:  -0.8420688827678662
# 4
# log ratio OIII_HB:  nan
# log ratio NII_HA:  -0.4747365152559381
# log ratio SII_HA:  -0.7936096674925156
# err NII/HA: 0.06616291648857113
# err SII/HA: 0.11282498442309527
# log ratio OIII_HB_c:  -0.2165490148135685
# log ratio NII_HA_c:  -0.6271449363066115
# log ratio SII_HA_c:  -0.6905811409934038
# 6
# log ratio OIII_HB:  0.28009852234522425
# log ratio NII_HA:  -0.779326808668266
# log ratio SII_HA:  -0.7608497792038234
# err OIII/HB: 0.10822611034362432
# err NII/HA: 0.05070009803388544
# err SII/HA: 0.061641229163849155
# log ratio OIII_HB_c:  0.15948067458267726
# log ratio NII_HA_c:  -0.764303240891178
# log ratio SII_HA_c:  -0.7423227265983264
# 3
# log ratio OIII_HB:  0.3733684454777196
# log ratio NII_HA:  -0.7191052521481293
# log ratio SII_HA:  -0.8330426432917722
# err OIII/HB: 0.6956013352579419
# err NII/HA: 0.08191224848650157
# err SII/HA: 0.08253500909780725
# log ratio OIII_HB_c:  -0.1761297080295004
# log ratio NII_HA_c:  -0.5896843626812501
# log ratio SII_HA_c:  -0.6445421126529567
# 5
# log ratio OIII_HB:  0.09711023880946416
# log ratio NII_HA:  -0.7539308523675425
# log ratio SII_HA:  -1.8502110602311876
# err OIII/HB: 0.2378714449617603
# err NII/HA: 0.2398265567043239
# err SII/HA: 3.4017054017039396
# log ratio OIII_HB_c:  0.031069349225349336
# log ratio NII_HA_c:  -0.7373892289668744
# log ratio SII_HA_c:  -0.7403084417324245
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5), sharey = True)
fig.suptitle('BPT subtraction 1s')
for i in range(7):    
    ax[0].errorbar(x = NII_HA[i], y = OIII_HB[i], xerr = err_NII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
               markersize = 4, marker = 'o')
    ax[1].errorbar(x = SII_HA[i], y = OIII_HB[i], xerr = err_SII_HA[i], yerr = err_OIII_HB[i], color = colors[i], 
              markersize = 4, marker = 'o')

x = np.linspace(-2, 0.04, num=200)
x1 = np.linspace(-2, 0.457, num=200)
x2 = np.linspace(-2, -0.25, num=200)
x3 = np.linspace(-0.49, 5, num=200)
ax[0].plot(x, Ku03(x), label = 'K03')
ax[0].plot(x1, Ke01(x1), label = 'K01')
ax[0].plot(x2, S06(x2), label = 'S06')

ax[0].plot(x3, C10(x3), label = 'C10')    
ax[0].set_xlim(-2, 1)
ax[0].set_ylim(-1.5, 2)
ax[0].set_xlabel('log([NII]λ6583/Hα)', fontsize=12)
ax[0].set_ylabel('log([OIII]λ5007/Hβ)', fontsize=12)
ax[0].legend()

x = np.linspace(-2, 0.1, num=200)
x1 = np.linspace(-0.31, 1, num=200)
ax[1].plot(x, Ke01_SII(x), label = 'Ke01_SII')
ax[1].plot(x1, Ke06(x1), label = 'Ke06')

ax[1].set_xlim(-2, 1)
ax[1].set_ylim(-1.5, 2)
ax[1].set_xlabel('log([SII]λ6583/Hα)', fontsize=12)
ax[1].legend()

plt.subplots_adjust(wspace=0.07)
plt.savefig('BPT_diff_1s.png', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
