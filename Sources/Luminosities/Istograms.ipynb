# %%
from astropy.io import fits
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lum_1 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_1/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_2 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/FIRSTJ110949/FIRSTJ110949_2/Spectra_extraction/OIII_extr/3Sigma/Luminosities/Luminosities.csv")
lum_3 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-02-017/MGC+01-02-017_1/FORS2.2021-10-04T04_41_52.988/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_4 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/FORS2.2022-01-29T07_05_26.457/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_5 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Extracted_spectra/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_6 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/4_peaks/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_7 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_8 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_9 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Extracted_spectra/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_10 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_1/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_11 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_12 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_13 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC4904/FORS2.2022-02-07T08_36_57.209/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_14 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_15 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_16 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_2/FORS2.2021-10-05T05_40_37.236/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_17 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC3141/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_18 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_1/FORS2.2022-01-07T06_54_16.725/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_19 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC5823/UGC5823_2/FORS2.2022-01-07T07_40_46.357/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_20 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv")
lum_21 = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_2/FORS2.2022-01-30T07_40_05.209/Spectra_extraction/OIII_ext/3Sigma/Luminosities/Luminosities.csv") 

# Lista con tutti i dataframe
all_dataframes = [lum_1, lum_2, lum_3, lum_4, lum_5, lum_6, lum_7, lum_8, 
                  lum_9, lum_10, lum_11, lum_12, lum_13, lum_14, lum_15, 
                  lum_16, lum_17, lum_18, lum_19, lum_20, lum_21]

# Liste per raccogliere i valori
Lx_values = []
Lbol_values = []

# Estrai le colonne da ogni dataframe
for df in all_dataframes:
    if 'LX' in df.columns and 'Lbol' in df.columns:
        Lx_values.extend(df['LX'].dropna().values)  # LX con X maiuscola
        Lbol_values.extend(df['Lbol'].dropna().values)

# Converti in array numpy (opzionale)
Lx_array = np.array(Lx_values)
Lbol_array = np.array(Lbol_values)

print(f"Numero di valori Lx: {len(Lx_array)}")
print(f"Numero di valori Lbol: {len(Lbol_array)}")
# Out:
# Numero di valori Lx: 94
# Numero di valori Lbol: 28

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].hist(Lx_array, bins=20, edgecolor='black', zorder =1, color = 'cornflowerblue')
axes[0].set_xlabel(r'$L_X [erg/s]$')
axes[0].set_ylabel('Number of nuclei')
axes[0].set_title(r'Distribuzion of $L_X$')
#axes[0].grid(True, alpha=0.3)

axes[1].hist(Lbol_array, bins=10, edgecolor='black', zorder =1, color = 'cornflowerblue')
axes[1].set_xlabel(r'$L_{bol} [erg/s]$')
axes[1].set_ylabel('Number of nuclei')
axes[1].set_title(r'Distribuzion of $L_{bol}$')
#axes[1].grid(True, alpha=0.3, zorder = 0)

plt.tight_layout()
plt.savefig('Luminosities_hist.png')
plt.show()

# %%
np.median(Lbol_values)
# Out:
# 1.4550000000000001e+41

# %%
separation = [10.6, 0.65, 1.17,2.7, 0.63, 0.28, 1.94, 0.67, 0.68]

plt.hist(separation, bins=7, edgecolor='black', zorder =1, color = 'cornflowerblue')
plt.xlabel(r'$L_X [erg/s]$')
plt.ylabel('Number of nuclei')
plt.title(r'Distribuzion of $L_X$')
# Out:
# Text(0.5, 1.0, 'Distribuzion of $L_X$')
