# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA (ampiezza dell'intervallo sulle x è +- la metà del seeing) e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/UGC-409_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/UGC-409_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     361   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        42   (2094, 964)   float32

# %%
image_cut = image[55:175, 0:1890]
image_error_cut = image_error[55:175, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.01736
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/PSF/Real_seeing_UGC409.txt")
sigmas = seeing / 2.35
print(sigmas)
# Out:
# [2.18004842 2.5199744  2.17810166 2.16914413 2.48282011 2.19531915]

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/UGC-409_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[55:175, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/UGC-409_1_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     361   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        42   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 80)*(y < 90)
mask_wv = wv > 0
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/Propag_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 120, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n_component = 5

def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])+
        sersic_1d(x_hr, *params[16:20]) #+
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 1.4)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 1.4)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (20, 30),   # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (45, 48),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (59, 65),
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 20),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 70),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (102, 103),
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 36202.529625560564
# differential_evolution step 2: f(x)= 3282.2340943069867
# differential_evolution step 3: f(x)= 3282.2340943069867
# differential_evolution step 4: f(x)= 3282.2340943069867
# differential_evolution step 5: f(x)= 3282.2340943069867
# differential_evolution step 6: f(x)= 3282.2340943069867
# differential_evolution step 7: f(x)= 3282.2340943069867
# differential_evolution step 8: f(x)= 3282.2340943069867
# differential_evolution step 9: f(x)= 3282.2340943069867
# differential_evolution step 10: f(x)= 2553.499234426295
# differential_evolution step 11: f(x)= 1410.1470646012099
# differential_evolution step 12: f(x)= 1410.1470646012099
# differential_evolution step 13: f(x)= 1410.1470646012099
# differential_evolution step 14: f(x)= 1410.1470646012099
# differential_evolution step 15: f(x)= 1410.1470646012099
# differential_evolution step 16: f(x)= 1410.1470646012099
# differential_evolution step 17: f(x)= 731.0711160572579
# differential_evolution step 18: f(x)= 731.0711160572579
# differential_evolution step 19: f(x)= 731.0711160572579
# differential_evolution step 20: f(x)= 464.3857559513309
# differential_evolution step 21: f(x)= 464.3857559513309
# differential_evolution step 22: f(x)= 464.3857559513309
# differential_evolution step 23: f(x)= 464.3857559513309
# differential_evolution step 24: f(x)= 146.1519728902937
# differential_evolution step 25: f(x)= 146.1519728902937
# differential_evolution step 26: f(x)= 146.1519728902937
# differential_evolution step 27: f(x)= 146.1519728902937
# differential_evolution step 28: f(x)= 146.1519728902937
# differential_evolution step 29: f(x)= 146.1519728902937
# differential_evolution step 30: f(x)= 84.70123096764316
# differential_evolution step 31: f(x)= 84.70123096764316
# differential_evolution step 32: f(x)= 84.70123096764316
# differential_evolution step 33: f(x)= 84.70123096764316
# differential_evolution step 34: f(x)= 84.70123096764316
# differential_evolution step 35: f(x)= 84.70123096764316
# differential_evolution step 36: f(x)= 84.70123096764316
# differential_evolution step 37: f(x)= 84.70123096764316
# differential_evolution step 38: f(x)= 84.70123096764316
# differential_evolution step 39: f(x)= 84.70123096764316
# differential_evolution step 40: f(x)= 84.70123096764316
# differential_evolution step 41: f(x)= 33.50487485139479
# differential_evolution step 42: f(x)= 33.50487485139479
# differential_evolution step 43: f(x)= 33.50487485139479
# differential_evolution step 44: f(x)= 33.50487485139479
# differential_evolution step 45: f(x)= 33.13203509791634
# differential_evolution step 46: f(x)= 33.13203509791634
# differential_evolution step 47: f(x)= 33.13203509791634
# differential_evolution step 48: f(x)= 24.315922787473845
# differential_evolution step 49: f(x)= 24.315922787473845
# differential_evolution step 50: f(x)= 24.315922787473845
# differential_evolution step 51: f(x)= 24.315922787473845
# differential_evolution step 52: f(x)= 24.315922787473845
# differential_evolution step 53: f(x)= 24.315922787473845
# differential_evolution step 54: f(x)= 24.315922787473845
# differential_evolution step 55: f(x)= 24.315922787473845
# differential_evolution step 56: f(x)= 24.315922787473845
# differential_evolution step 57: f(x)= 24.315922787473845
# differential_evolution step 58: f(x)= 24.315922787473845
# differential_evolution step 59: f(x)= 24.315922787473845
# differential_evolution step 60: f(x)= 24.315922787473845
# differential_evolution step 61: f(x)= 24.315922787473845
# differential_evolution step 62: f(x)= 24.315922787473845
# differential_evolution step 63: f(x)= 24.315922787473845
# differential_evolution step 64: f(x)= 24.315922787473845
# differential_evolution step 65: f(x)= 24.315922787473845
# differential_evolution step 66: f(x)= 24.315922787473845
# differential_evolution step 67: f(x)= 24.315922787473845
# differential_evolution step 68: f(x)= 24.315922787473845
# differential_evolution step 69: f(x)= 24.315922787473845
# differential_evolution step 70: f(x)= 24.315922787473845
# differential_evolution step 71: f(x)= 24.315922787473845
# differential_evolution step 72: f(x)= 24.315922787473845
# differential_evolution step 73: f(x)= 24.315922787473845
# differential_evolution step 74: f(x)= 24.315922787473845
# differential_evolution step 75: f(x)= 20.344221376869772
# differential_evolution step 76: f(x)= 20.344221376869772
# differential_evolution step 77: f(x)= 20.344221376869772
# differential_evolution step 78: f(x)= 20.344221376869772
# differential_evolution step 79: f(x)= 20.344221376869772
# differential_evolution step 80: f(x)= 17.350258821761557
# differential_evolution step 81: f(x)= 17.350258821761557
# differential_evolution step 82: f(x)= 17.350258821761557
# differential_evolution step 83: f(x)= 17.350258821761557
# differential_evolution step 84: f(x)= 17.350258821761557
# differential_evolution step 85: f(x)= 17.350258821761557
# differential_evolution step 86: f(x)= 17.350258821761557
# differential_evolution step 87: f(x)= 17.350258821761557
# differential_evolution step 88: f(x)= 17.350258821761557
# differential_evolution step 89: f(x)= 17.350258821761557
# differential_evolution step 90: f(x)= 16.037029296757318
# differential_evolution step 91: f(x)= 8.16070707964858
# differential_evolution step 92: f(x)= 8.16070707964858
# differential_evolution step 93: f(x)= 8.16070707964858
# differential_evolution step 94: f(x)= 8.16070707964858
# differential_evolution step 95: f(x)= 8.16070707964858
# differential_evolution step 96: f(x)= 8.16070707964858
# differential_evolution step 97: f(x)= 8.16070707964858
# differential_evolution step 98: f(x)= 8.16070707964858
# differential_evolution step 99: f(x)= 6.1886705805028
# differential_evolution step 100: f(x)= 6.1886705805028
# differential_evolution step 101: f(x)= 6.1886705805028
# differential_evolution step 102: f(x)= 3.877493271871688
# differential_evolution step 103: f(x)= 3.877493271871688
# differential_evolution step 104: f(x)= 3.877493271871688
# differential_evolution step 105: f(x)= 3.877493271871688
# differential_evolution step 106: f(x)= 3.705085772183317
# differential_evolution step 107: f(x)= 3.705085772183317
# differential_evolution step 108: f(x)= 3.705085772183317
# differential_evolution step 109: f(x)= 3.705085772183317
# differential_evolution step 110: f(x)= 3.705085772183317
# differential_evolution step 111: f(x)= 3.705085772183317
# differential_evolution step 112: f(x)= 3.367463381833123
# differential_evolution step 113: f(x)= 3.367463381833123
# differential_evolution step 114: f(x)= 3.367463381833123
# differential_evolution step 115: f(x)= 3.367463381833123
# differential_evolution step 116: f(x)= 3.367463381833123
# differential_evolution step 117: f(x)= 2.6874781391791926
# differential_evolution step 118: f(x)= 2.6874781391791926
# differential_evolution step 119: f(x)= 2.6874781391791926
# differential_evolution step 120: f(x)= 2.6874781391791926
# differential_evolution step 121: f(x)= 2.6874781391791926
# differential_evolution step 122: f(x)= 2.6874781391791926
# differential_evolution step 123: f(x)= 2.6874781391791926
# differential_evolution step 124: f(x)= 2.6874781391791926
# differential_evolution step 125: f(x)= 2.6874781391791926
# differential_evolution step 126: f(x)= 2.6874781391791926
# differential_evolution step 127: f(x)= 2.6874781391791926
# differential_evolution step 128: f(x)= 2.6874781391791926
# differential_evolution step 129: f(x)= 2.6874781391791926
# differential_evolution step 130: f(x)= 1.8070631197743183
# differential_evolution step 131: f(x)= 1.8070631197743183
# differential_evolution step 132: f(x)= 1.8070631197743183
# differential_evolution step 133: f(x)= 1.8070631197743183
# differential_evolution step 134: f(x)= 1.8070631197743183
# differential_evolution step 135: f(x)= 1.8070631197743183
# differential_evolution step 136: f(x)= 1.8070631197743183
# differential_evolution step 137: f(x)= 1.8070631197743183
# differential_evolution step 138: f(x)= 1.3051855862185913
# differential_evolution step 139: f(x)= 1.3051855862185913
# differential_evolution step 140: f(x)= 1.3051855862185913
# differential_evolution step 141: f(x)= 1.3051855862185913
# differential_evolution step 142: f(x)= 1.3051855862185913
# differential_evolution step 143: f(x)= 0.9302059177346479
# differential_evolution step 144: f(x)= 0.9302059177346479
# differential_evolution step 145: f(x)= 0.9302059177346479
# differential_evolution step 146: f(x)= 0.9302059177346479
# differential_evolution step 147: f(x)= 0.9302059177346479
# differential_evolution step 148: f(x)= 0.9302059177346479
# differential_evolution step 149: f(x)= 0.9302059177346479
# differential_evolution step 150: f(x)= 0.9302059177346479
# differential_evolution step 151: f(x)= 0.9302059177346479
# differential_evolution step 152: f(x)= 0.9302059177346479
# differential_evolution step 153: f(x)= 0.9302059177346479
# differential_evolution step 154: f(x)= 0.9302059177346479
# differential_evolution step 155: f(x)= 0.9302059177346479
# differential_evolution step 156: f(x)= 0.9302059177346479
# differential_evolution step 157: f(x)= 0.9302059177346479
# differential_evolution step 158: f(x)= 0.9302059177346479
# differential_evolution step 159: f(x)= 0.9302059177346479
# differential_evolution step 160: f(x)= 0.9302059177346479
# differential_evolution step 161: f(x)= 0.9302059177346479
# differential_evolution step 162: f(x)= 0.9302059177346479
# differential_evolution step 163: f(x)= 0.9302059177346479
# differential_evolution step 164: f(x)= 0.9302059177346479
# differential_evolution step 165: f(x)= 0.9302059177346479
# differential_evolution step 166: f(x)= 0.9302059177346479
# differential_evolution step 167: f(x)= 0.9302059177346479
# differential_evolution step 168: f(x)= 0.9302059177346479
# differential_evolution step 169: f(x)= 0.9302059177346479
# differential_evolution step 170: f(x)= 0.9302059177346479
# differential_evolution step 171: f(x)= 0.9302059177346479
# differential_evolution step 172: f(x)= 0.9302059177346479
# differential_evolution step 173: f(x)= 0.9302059177346479
# differential_evolution step 174: f(x)= 0.9302059177346479
# differential_evolution step 175: f(x)= 0.9302059177346479
# differential_evolution step 176: f(x)= 0.9302059177346479
# differential_evolution step 177: f(x)= 0.9302059177346479
# differential_evolution step 178: f(x)= 0.9302059177346479
# differential_evolution step 179: f(x)= 0.9302059177346479
# differential_evolution step 180: f(x)= 0.5985418568861298
# differential_evolution step 181: f(x)= 0.5985418568861298
# differential_evolution step 182: f(x)= 0.5985418568861298
# differential_evolution step 183: f(x)= 0.5985418568861298
# differential_evolution step 184: f(x)= 0.5985418568861298
# differential_evolution step 185: f(x)= 0.5985418568861298
# differential_evolution step 186: f(x)= 0.5985418568861298
# differential_evolution step 187: f(x)= 0.5785506511457076
# differential_evolution step 188: f(x)= 0.5785506511457076
# differential_evolution step 189: f(x)= 0.5785506511457076
# differential_evolution step 190: f(x)= 0.5785506511457076
# differential_evolution step 191: f(x)= 0.5785506511457076
# differential_evolution step 192: f(x)= 0.5785506511457076
# differential_evolution step 193: f(x)= 0.5785506511457076
# differential_evolution step 194: f(x)= 0.5785506511457076
# differential_evolution step 195: f(x)= 0.48078588708515413
# differential_evolution step 196: f(x)= 0.48078588708515413
# differential_evolution step 197: f(x)= 0.48078588708515413
# differential_evolution step 198: f(x)= 0.48078588708515413
# differential_evolution step 199: f(x)= 0.48078588708515413
# differential_evolution step 200: f(x)= 0.48078588708515413
# differential_evolution step 201: f(x)= 0.48078588708515413
# differential_evolution step 202: f(x)= 0.28860628037729963
# differential_evolution step 203: f(x)= 0.28860628037729963
# differential_evolution step 204: f(x)= 0.28860628037729963
# differential_evolution step 205: f(x)= 0.28860628037729963
# differential_evolution step 206: f(x)= 0.28860628037729963
# differential_evolution step 207: f(x)= 0.28860628037729963
# differential_evolution step 208: f(x)= 0.28860628037729963
# differential_evolution step 209: f(x)= 0.2853995622681902
# differential_evolution step 210: f(x)= 0.2853995622681902
# differential_evolution step 211: f(x)= 0.2853995622681902
# differential_evolution step 212: f(x)= 0.2853995622681902
# differential_evolution step 213: f(x)= 0.2853995622681902
# differential_evolution step 214: f(x)= 0.2853995622681902
# differential_evolution step 215: f(x)= 0.2853995622681902
# differential_evolution step 216: f(x)= 0.2853995622681902
# differential_evolution step 217: f(x)= 0.21326002008708633
# differential_evolution step 218: f(x)= 0.21326002008708633
# differential_evolution step 219: f(x)= 0.21326002008708633
# differential_evolution step 220: f(x)= 0.21326002008708633
# differential_evolution step 221: f(x)= 0.21326002008708633
# differential_evolution step 222: f(x)= 0.21326002008708633
# differential_evolution step 223: f(x)= 0.21326002008708633
# differential_evolution step 224: f(x)= 0.21326002008708633
# differential_evolution step 225: f(x)= 0.16379281390793846
# differential_evolution step 226: f(x)= 0.16379281390793846
# differential_evolution step 227: f(x)= 0.16379281390793846
# differential_evolution step 228: f(x)= 0.16379281390793846
# differential_evolution step 229: f(x)= 0.16379281390793846
# differential_evolution step 230: f(x)= 0.16379281390793846
# differential_evolution step 231: f(x)= 0.16379281390793846
# differential_evolution step 232: f(x)= 0.16379281390793846
# differential_evolution step 233: f(x)= 0.16379281390793846
# differential_evolution step 234: f(x)= 0.16379281390793846
# differential_evolution step 235: f(x)= 0.16379281390793846
# differential_evolution step 236: f(x)= 0.16379281390793846
# differential_evolution step 237: f(x)= 0.16379281390793846
# differential_evolution step 238: f(x)= 0.14469058782364272
# differential_evolution step 239: f(x)= 0.14469058782364272
# differential_evolution step 240: f(x)= 0.14469058782364272
# differential_evolution step 241: f(x)= 0.14469058782364272
# differential_evolution step 242: f(x)= 0.14469058782364272
# differential_evolution step 243: f(x)= 0.14469058782364272
# differential_evolution step 244: f(x)= 0.1179435613709344
# differential_evolution step 245: f(x)= 0.1179435613709344
# differential_evolution step 246: f(x)= 0.1179435613709344
# differential_evolution step 247: f(x)= 0.1179435613709344
# differential_evolution step 248: f(x)= 0.1179435613709344
# differential_evolution step 249: f(x)= 0.1179435613709344
# differential_evolution step 250: f(x)= 0.1179435613709344
# differential_evolution step 251: f(x)= 0.1179435613709344
# differential_evolution step 252: f(x)= 0.1179435613709344
# differential_evolution step 253: f(x)= 0.1179435613709344
# differential_evolution step 254: f(x)= 0.1179435613709344
# differential_evolution step 255: f(x)= 0.1179435613709344
# differential_evolution step 256: f(x)= 0.1179435613709344
# differential_evolution step 257: f(x)= 0.1179435613709344
# differential_evolution step 258: f(x)= 0.1179435613709344
# differential_evolution step 259: f(x)= 0.1179435613709344
# differential_evolution step 260: f(x)= 0.1179435613709344
# differential_evolution step 261: f(x)= 0.1179435613709344
# differential_evolution step 262: f(x)= 0.10909591541554815
# differential_evolution step 263: f(x)= 0.08211223671583007
# differential_evolution step 264: f(x)= 0.08211223671583007
# differential_evolution step 265: f(x)= 0.07350321450936052
# differential_evolution step 266: f(x)= 0.07350321450936052
# differential_evolution step 267: f(x)= 0.07350321450936052
# differential_evolution step 268: f(x)= 0.07350321450936052
# differential_evolution step 269: f(x)= 0.07350321450936052
# differential_evolution step 270: f(x)= 0.07350321450936052
# differential_evolution step 271: f(x)= 0.07350321450936052
# differential_evolution step 272: f(x)= 0.07350321450936052
# differential_evolution step 273: f(x)= 0.07350321450936052
# differential_evolution step 274: f(x)= 0.07350321450936052
# differential_evolution step 275: f(x)= 0.07350321450936052
# differential_evolution step 276: f(x)= 0.07350321450936052
# differential_evolution step 277: f(x)= 0.07350321450936052
# differential_evolution step 278: f(x)= 0.07350321450936052
# differential_evolution step 279: f(x)= 0.07350321450936052
# differential_evolution step 280: f(x)= 0.07350321450936052
# differential_evolution step 281: f(x)= 0.07350321450936052
# differential_evolution step 282: f(x)= 0.07350321450936052
# differential_evolution step 283: f(x)= 0.07350321450936052
# differential_evolution step 284: f(x)= 0.07350321450936052
# differential_evolution step 285: f(x)= 0.07350321450936052
# differential_evolution step 286: f(x)= 0.07350321450936052
# differential_evolution step 287: f(x)= 0.07350321450936052
# differential_evolution step 288: f(x)= 0.07350321450936052
# differential_evolution step 289: f(x)= 0.07350321450936052
# differential_evolution step 290: f(x)= 0.07350321450936052
# differential_evolution step 291: f(x)= 0.07350321450936052
# differential_evolution step 292: f(x)= 0.07350321450936052
# differential_evolution step 293: f(x)= 0.07350321450936052
# differential_evolution step 294: f(x)= 0.07350321450936052
# differential_evolution step 295: f(x)= 0.07350321450936052
# differential_evolution step 296: f(x)= 0.07350321450936052
# differential_evolution step 297: f(x)= 0.0726920746433864
# differential_evolution step 298: f(x)= 0.0726920746433864
# differential_evolution step 299: f(x)= 0.0726920746433864
# differential_evolution step 300: f(x)= 0.0726920746433864
# differential_evolution step 301: f(x)= 0.0726920746433864
# differential_evolution step 302: f(x)= 0.0726920746433864
# differential_evolution step 303: f(x)= 0.0726920746433864
# differential_evolution step 304: f(x)= 0.0726920746433864
# differential_evolution step 305: f(x)= 0.0726920746433864
# differential_evolution step 306: f(x)= 0.0726920746433864
# differential_evolution step 307: f(x)= 0.0726920746433864
# differential_evolution step 308: f(x)= 0.0726920746433864
# differential_evolution step 309: f(x)= 0.0726920746433864
# differential_evolution step 310: f(x)= 0.0726920746433864
# differential_evolution step 311: f(x)= 0.0726920746433864
# differential_evolution step 312: f(x)= 0.0726920746433864
# differential_evolution step 313: f(x)= 0.0726920746433864
# differential_evolution step 314: f(x)= 0.0726920746433864
# differential_evolution step 315: f(x)= 0.0726920746433864
# differential_evolution step 316: f(x)= 0.06524949709838754
# differential_evolution step 317: f(x)= 0.06524949709838754
# differential_evolution step 318: f(x)= 0.06524949709838754
# differential_evolution step 319: f(x)= 0.06524949709838754
# differential_evolution step 320: f(x)= 0.06524949709838754
# differential_evolution step 321: f(x)= 0.06513290603645147
# differential_evolution step 322: f(x)= 0.06443001704395857
# differential_evolution step 323: f(x)= 0.06443001704395857
# differential_evolution step 324: f(x)= 0.06443001704395857
# differential_evolution step 325: f(x)= 0.06443001704395857
# differential_evolution step 326: f(x)= 0.06443001704395857
# differential_evolution step 327: f(x)= 0.06443001704395857
# differential_evolution step 328: f(x)= 0.06443001704395857
# differential_evolution step 329: f(x)= 0.06443001704395857
# differential_evolution step 330: f(x)= 0.06443001704395857
# differential_evolution step 331: f(x)= 0.06443001704395857
# differential_evolution step 332: f(x)= 0.06443001704395857
# differential_evolution step 333: f(x)= 0.06443001704395857
# differential_evolution step 334: f(x)= 0.06443001704395857
# differential_evolution step 335: f(x)= 0.06443001704395857
# differential_evolution step 336: f(x)= 0.06443001704395857
# differential_evolution step 337: f(x)= 0.06443001704395857
# differential_evolution step 338: f(x)= 0.06443001704395857
# differential_evolution step 339: f(x)= 0.05658141483537395
# differential_evolution step 340: f(x)= 0.05658141483537395
# differential_evolution step 341: f(x)= 0.05658141483537395
# differential_evolution step 342: f(x)= 0.05658141483537395
# differential_evolution step 343: f(x)= 0.05658141483537395
# differential_evolution step 344: f(x)= 0.05658141483537395
# differential_evolution step 345: f(x)= 0.05658141483537395
# differential_evolution step 346: f(x)= 0.05658141483537395
# differential_evolution step 347: f(x)= 0.05658141483537395
# differential_evolution step 348: f(x)= 0.05658141483537395
# differential_evolution step 349: f(x)= 0.05658141483537395
# differential_evolution step 350: f(x)= 0.055127809200911156
# differential_evolution step 351: f(x)= 0.055127809200911156
# differential_evolution step 352: f(x)= 0.055127809200911156
# differential_evolution step 353: f(x)= 0.055127809200911156
# differential_evolution step 354: f(x)= 0.055127809200911156
# differential_evolution step 355: f(x)= 0.055127809200911156
# differential_evolution step 356: f(x)= 0.055127809200911156
# differential_evolution step 357: f(x)= 0.055127809200911156
# differential_evolution step 358: f(x)= 0.05356678341665223
# differential_evolution step 359: f(x)= 0.05356678341665223
# differential_evolution step 360: f(x)= 0.05356678341665223
# differential_evolution step 361: f(x)= 0.05356678341665223
# differential_evolution step 362: f(x)= 0.05356678341665223
# differential_evolution step 363: f(x)= 0.05356678341665223
# differential_evolution step 364: f(x)= 0.05356678341665223
# differential_evolution step 365: f(x)= 0.05356678341665223
# differential_evolution step 366: f(x)= 0.05356678341665223
# differential_evolution step 367: f(x)= 0.05356678341665223
# differential_evolution step 368: f(x)= 0.05356678341665223
# differential_evolution step 369: f(x)= 0.05356678341665223
# differential_evolution step 370: f(x)= 0.05356678341665223
# differential_evolution step 371: f(x)= 0.05356678341665223
# differential_evolution step 372: f(x)= 0.05356678341665223
# differential_evolution step 373: f(x)= 0.05294450185244713
# differential_evolution step 374: f(x)= 0.05294450185244713
# differential_evolution step 375: f(x)= 0.050869994768781276
# differential_evolution step 376: f(x)= 0.050729565315794915
# differential_evolution step 377: f(x)= 0.050729565315794915
# differential_evolution step 378: f(x)= 0.050729565315794915
# differential_evolution step 379: f(x)= 0.050729565315794915
# differential_evolution step 380: f(x)= 0.050729565315794915
# differential_evolution step 381: f(x)= 0.050729565315794915
# differential_evolution step 382: f(x)= 0.050729565315794915
# differential_evolution step 383: f(x)= 0.04591259597760961
# differential_evolution step 384: f(x)= 0.04591259597760961
# differential_evolution step 385: f(x)= 0.04591259597760961
# differential_evolution step 386: f(x)= 0.04555126568567856
# differential_evolution step 387: f(x)= 0.04555126568567856
# differential_evolution step 388: f(x)= 0.04555126568567856
# differential_evolution step 389: f(x)= 0.04555126568567856
# differential_evolution step 390: f(x)= 0.04555126568567856
# differential_evolution step 391: f(x)= 0.04555126568567856
# differential_evolution step 392: f(x)= 0.04555126568567856
# differential_evolution step 393: f(x)= 0.04555126568567856
# differential_evolution step 394: f(x)= 0.04555126568567856
# differential_evolution step 395: f(x)= 0.04555126568567856
# differential_evolution step 396: f(x)= 0.04555126568567856
# differential_evolution step 397: f(x)= 0.04436410064357794
# differential_evolution step 398: f(x)= 0.04436410064357794
# differential_evolution step 399: f(x)= 0.04436410064357794
# differential_evolution step 400: f(x)= 0.04436410064357794
# differential_evolution step 401: f(x)= 0.04436410064357794
# differential_evolution step 402: f(x)= 0.04436410064357794
# differential_evolution step 403: f(x)= 0.04436410064357794
# differential_evolution step 404: f(x)= 0.04436410064357794
# differential_evolution step 405: f(x)= 0.04436410064357794
# differential_evolution step 406: f(x)= 0.04436410064357794
# differential_evolution step 407: f(x)= 0.04436410064357794
# differential_evolution step 408: f(x)= 0.04436410064357794
# differential_evolution step 409: f(x)= 0.04436410064357794
# differential_evolution step 410: f(x)= 0.04436410064357794
# differential_evolution step 411: f(x)= 0.04436410064357794
# differential_evolution step 412: f(x)= 0.04368718584273014
# differential_evolution step 413: f(x)= 0.04368718584273014
# differential_evolution step 414: f(x)= 0.04368718584273014
# differential_evolution step 415: f(x)= 0.04368718584273014
# differential_evolution step 416: f(x)= 0.04368718584273014
# differential_evolution step 417: f(x)= 0.04368718584273014
# differential_evolution step 418: f(x)= 0.04190384413561961
# differential_evolution step 419: f(x)= 0.04190384413561961
# differential_evolution step 420: f(x)= 0.04190384413561961
# differential_evolution step 421: f(x)= 0.04190384413561961
# differential_evolution step 422: f(x)= 0.04190384413561961
# differential_evolution step 423: f(x)= 0.04190384413561961
# differential_evolution step 424: f(x)= 0.04190384413561961
# differential_evolution step 425: f(x)= 0.04190384413561961
# differential_evolution step 426: f(x)= 0.04190384413561961
# differential_evolution step 427: f(x)= 0.04190384413561961
# differential_evolution step 428: f(x)= 0.04190384413561961
# differential_evolution step 429: f(x)= 0.04190384413561961
# differential_evolution step 430: f(x)= 0.04190384413561961
# differential_evolution step 431: f(x)= 0.041839929625915796
# differential_evolution step 432: f(x)= 0.041839929625915796
# differential_evolution step 433: f(x)= 0.03852943025587889
# differential_evolution step 434: f(x)= 0.03852943025587889
# differential_evolution step 435: f(x)= 0.03852943025587889
# differential_evolution step 436: f(x)= 0.03852943025587889
# differential_evolution step 437: f(x)= 0.03852943025587889
# differential_evolution step 438: f(x)= 0.03852943025587889
# differential_evolution step 439: f(x)= 0.03852943025587889
# differential_evolution step 440: f(x)= 0.03852943025587889
# differential_evolution step 441: f(x)= 0.03852943025587889
# differential_evolution step 442: f(x)= 0.03852943025587889
# differential_evolution step 443: f(x)= 0.03852943025587889
# differential_evolution step 444: f(x)= 0.03852943025587889
# differential_evolution step 445: f(x)= 0.03852943025587889
# differential_evolution step 446: f(x)= 0.03852943025587889
# differential_evolution step 447: f(x)= 0.03852943025587889
# differential_evolution step 448: f(x)= 0.03852943025587889
# differential_evolution step 449: f(x)= 0.03852943025587889
# differential_evolution step 450: f(x)= 0.03852943025587889
# differential_evolution step 451: f(x)= 0.03852943025587889
# differential_evolution step 452: f(x)= 0.03852943025587889
# differential_evolution step 453: f(x)= 0.03852943025587889
# differential_evolution step 454: f(x)= 0.03852943025587889
# differential_evolution step 455: f(x)= 0.03852943025587889
# differential_evolution step 456: f(x)= 0.03852943025587889
# differential_evolution step 457: f(x)= 0.03852943025587889
# differential_evolution step 458: f(x)= 0.03852943025587889
# differential_evolution step 459: f(x)= 0.03852943025587889
# differential_evolution step 460: f(x)= 0.03244648992859857
# differential_evolution step 461: f(x)= 0.03244648992859857
# differential_evolution step 462: f(x)= 0.03244648992859857
# differential_evolution step 463: f(x)= 0.03244648992859857
# differential_evolution step 464: f(x)= 0.03244648992859857
# differential_evolution step 465: f(x)= 0.03244648992859857
# differential_evolution step 466: f(x)= 0.03244648992859857
# differential_evolution step 467: f(x)= 0.03244648992859857
# differential_evolution step 468: f(x)= 0.03244648992859857
# differential_evolution step 469: f(x)= 0.03244648992859857
# differential_evolution step 470: f(x)= 0.03244648992859857
# differential_evolution step 471: f(x)= 0.03244648992859857
# differential_evolution step 472: f(x)= 0.03244648992859857
# differential_evolution step 561: f(x)= 0.02430333072930333
# differential_evolution step 562: f(x)= 0.02430333072930333
# differential_evolution step 563: f(x)= 0.02430333072930333
# differential_evolution step 564: f(x)= 0.02430333072930333
# differential_evolution step 565: f(x)= 0.02430333072930333
# differential_evolution step 566: f(x)= 0.02430333072930333
# differential_evolution step 567: f(x)= 0.02430333072930333
# differential_evolution step 568: f(x)= 0.02430333072930333
# differential_evolution step 569: f(x)= 0.02430333072930333
# differential_evolution step 570: f(x)= 0.02430333072930333
# differential_evolution step 571: f(x)= 0.02430333072930333
# differential_evolution step 572: f(x)= 0.02430333072930333
# differential_evolution step 573: f(x)= 0.02430333072930333
# differential_evolution step 574: f(x)= 0.02430333072930333
# differential_evolution step 575: f(x)= 0.02430333072930333
# differential_evolution step 576: f(x)= 0.02430333072930333
# differential_evolution step 577: f(x)= 0.02430333072930333
# differential_evolution step 578: f(x)= 0.02430333072930333
# differential_evolution step 579: f(x)= 0.02430333072930333
# differential_evolution step 580: f(x)= 0.02430333072930333
# differential_evolution step 581: f(x)= 0.02430333072930333
# differential_evolution step 582: f(x)= 0.02430333072930333
# differential_evolution step 583: f(x)= 0.02430333072930333
# differential_evolution step 584: f(x)= 0.02430333072930333
# differential_evolution step 585: f(x)= 0.02430333072930333
# differential_evolution step 586: f(x)= 0.02430333072930333
# differential_evolution step 587: f(x)= 0.02430333072930333
# differential_evolution step 588: f(x)= 0.02430333072930333
# differential_evolution step 589: f(x)= 0.02430333072930333
# differential_evolution step 590: f(x)= 0.02430333072930333
# differential_evolution step 591: f(x)= 0.02430333072930333
# differential_evolution step 592: f(x)= 0.02430333072930333
# differential_evolution step 593: f(x)= 0.02430333072930333
# differential_evolution step 594: f(x)= 0.02430333072930333
# differential_evolution step 595: f(x)= 0.023755005148687162
# differential_evolution step 596: f(x)= 0.023755005148687162
# differential_evolution step 597: f(x)= 0.023755005148687162
# differential_evolution step 598: f(x)= 0.023755005148687162
# differential_evolution step 599: f(x)= 0.023755005148687162
# differential_evolution step 600: f(x)= 0.023755005148687162
# differential_evolution step 601: f(x)= 0.023755005148687162
# differential_evolution step 602: f(x)= 0.022917677845164228
# differential_evolution step 603: f(x)= 0.022917677845164228
# differential_evolution step 604: f(x)= 0.022917677845164228
# differential_evolution step 605: f(x)= 0.022917677845164228
# differential_evolution step 606: f(x)= 0.022917677845164228
# differential_evolution step 607: f(x)= 0.022917677845164228
# differential_evolution step 608: f(x)= 0.022917677845164228
# differential_evolution step 609: f(x)= 0.022917677845164228
# differential_evolution step 610: f(x)= 0.022577065902685562
# differential_evolution step 611: f(x)= 0.022262733888484904
# differential_evolution step 612: f(x)= 0.022262733888484904
# differential_evolution step 613: f(x)= 0.022262733888484904
# differential_evolution step 614: f(x)= 0.022262733888484904
# differential_evolution step 615: f(x)= 0.022262733888484904
# differential_evolution step 616: f(x)= 0.02139965302197358
# differential_evolution step 617: f(x)= 0.02139965302197358
# differential_evolution step 618: f(x)= 0.01972124181476169
# differential_evolution step 619: f(x)= 0.01972124181476169
# differential_evolution step 620: f(x)= 0.01972124181476169
# differential_evolution step 621: f(x)= 0.01972124181476169
# differential_evolution step 622: f(x)= 0.01972124181476169
# differential_evolution step 623: f(x)= 0.01972124181476169
# differential_evolution step 624: f(x)= 0.01972124181476169
# differential_evolution step 625: f(x)= 0.01972124181476169
# differential_evolution step 626: f(x)= 0.01972124181476169
# differential_evolution step 627: f(x)= 0.01972124181476169
# differential_evolution step 628: f(x)= 0.01972124181476169
# differential_evolution step 629: f(x)= 0.01972124181476169
# differential_evolution step 630: f(x)= 0.01972124181476169
# differential_evolution step 631: f(x)= 0.01972124181476169
# differential_evolution step 632: f(x)= 0.01972124181476169
# differential_evolution step 633: f(x)= 0.01972124181476169
# differential_evolution step 634: f(x)= 0.01972124181476169
# differential_evolution step 635: f(x)= 0.01972124181476169
# differential_evolution step 636: f(x)= 0.01972124181476169
# differential_evolution step 637: f(x)= 0.01972124181476169
# differential_evolution step 638: f(x)= 0.018726034577789374
# differential_evolution step 639: f(x)= 0.018726034577789374
# differential_evolution step 640: f(x)= 0.018726034577789374
# differential_evolution step 641: f(x)= 0.018726034577789374
# differential_evolution step 642: f(x)= 0.018726034577789374
# differential_evolution step 643: f(x)= 0.018726034577789374
# differential_evolution step 644: f(x)= 0.018726034577789374
# differential_evolution step 645: f(x)= 0.018726034577789374
# differential_evolution step 646: f(x)= 0.018726034577789374
# differential_evolution step 647: f(x)= 0.018726034577789374
# differential_evolution step 648: f(x)= 0.018726034577789374
# differential_evolution step 649: f(x)= 0.018726034577789374
# differential_evolution step 650: f(x)= 0.018726034577789374
# differential_evolution step 651: f(x)= 0.018726034577789374
# differential_evolution step 652: f(x)= 0.018726034577789374
# differential_evolution step 653: f(x)= 0.018726034577789374
# differential_evolution step 654: f(x)= 0.018726034577789374
# differential_evolution step 655: f(x)= 0.018726034577789374
# differential_evolution step 656: f(x)= 0.018726034577789374
# differential_evolution step 657: f(x)= 0.018726034577789374
# differential_evolution step 658: f(x)= 0.018726034577789374
# differential_evolution step 659: f(x)= 0.018726034577789374
# differential_evolution step 660: f(x)= 0.018726034577789374
# differential_evolution step 661: f(x)= 0.018726034577789374
# differential_evolution step 662: f(x)= 0.018726034577789374
# differential_evolution step 663: f(x)= 0.018726034577789374
# differential_evolution step 664: f(x)= 0.018726034577789374
# differential_evolution step 665: f(x)= 0.018726034577789374
# differential_evolution step 666: f(x)= 0.018726034577789374
# differential_evolution step 667: f(x)= 0.018726034577789374
# differential_evolution step 668: f(x)= 0.018726034577789374
# differential_evolution step 669: f(x)= 0.018726034577789374
# differential_evolution step 670: f(x)= 0.018726034577789374
# differential_evolution step 671: f(x)= 0.018726034577789374
# differential_evolution step 672: f(x)= 0.018726034577789374
# differential_evolution step 673: f(x)= 0.018726034577789374
# differential_evolution step 674: f(x)= 0.018726034577789374
# differential_evolution step 675: f(x)= 0.018726034577789374
# differential_evolution step 676: f(x)= 0.018726034577789374
# differential_evolution step 677: f(x)= 0.018726034577789374
# differential_evolution step 678: f(x)= 0.018726034577789374
# differential_evolution step 679: f(x)= 0.018726034577789374
# differential_evolution step 680: f(x)= 0.018726034577789374
# differential_evolution step 681: f(x)= 0.018726034577789374
# differential_evolution step 682: f(x)= 0.018726034577789374
# differential_evolution step 683: f(x)= 0.018726034577789374
# differential_evolution step 684: f(x)= 0.018726034577789374
# differential_evolution step 685: f(x)= 0.018310025288332216
# differential_evolution step 686: f(x)= 0.018310025288332216
# differential_evolution step 687: f(x)= 0.0172907413142004
# differential_evolution step 688: f(x)= 0.01658323496632442
# differential_evolution step 689: f(x)= 0.01658323496632442
# differential_evolution step 690: f(x)= 0.01658323496632442
# differential_evolution step 691: f(x)= 0.01658323496632442
# differential_evolution step 692: f(x)= 0.01658323496632442
# differential_evolution step 693: f(x)= 0.01658323496632442
# differential_evolution step 694: f(x)= 0.01658323496632442
# differential_evolution step 695: f(x)= 0.01658323496632442
# differential_evolution step 696: f(x)= 0.01658323496632442
# differential_evolution step 697: f(x)= 0.01658323496632442
# differential_evolution step 698: f(x)= 0.01658323496632442
# differential_evolution step 699: f(x)= 0.01658323496632442
# differential_evolution step 700: f(x)= 0.01658323496632442
# differential_evolution step 701: f(x)= 0.01658323496632442
# differential_evolution step 702: f(x)= 0.01658323496632442
# differential_evolution step 703: f(x)= 0.01658323496632442
# differential_evolution step 704: f(x)= 0.01658323496632442
# differential_evolution step 705: f(x)= 0.01658323496632442
# differential_evolution step 706: f(x)= 0.01658323496632442
# differential_evolution step 707: f(x)= 0.01658323496632442
# differential_evolution step 708: f(x)= 0.01658323496632442
# differential_evolution step 709: f(x)= 0.01658323496632442
# differential_evolution step 710: f(x)= 0.01658323496632442
# differential_evolution step 711: f(x)= 0.01658323496632442
# differential_evolution step 712: f(x)= 0.01658323496632442
# differential_evolution step 713: f(x)= 0.01658323496632442
# differential_evolution step 714: f(x)= 0.01658323496632442
# differential_evolution step 715: f(x)= 0.01658323496632442
# differential_evolution step 716: f(x)= 0.01654578437526753
# differential_evolution step 717: f(x)= 0.01654578437526753
# differential_evolution step 718: f(x)= 0.01654578437526753
# differential_evolution step 719: f(x)= 0.01654578437526753
# differential_evolution step 720: f(x)= 0.01654578437526753
# differential_evolution step 721: f(x)= 0.01654578437526753
# differential_evolution step 722: f(x)= 0.01654578437526753
# differential_evolution step 723: f(x)= 0.01654578437526753
# differential_evolution step 724: f(x)= 0.01654578437526753
# differential_evolution step 725: f(x)= 0.01654578437526753
# differential_evolution step 726: f(x)= 0.01654578437526753
# differential_evolution step 727: f(x)= 0.01654578437526753
# differential_evolution step 728: f(x)= 0.01654578437526753
# differential_evolution step 729: f(x)= 0.01654578437526753
# differential_evolution step 730: f(x)= 0.01654578437526753
# differential_evolution step 731: f(x)= 0.01654578437526753
# differential_evolution step 732: f(x)= 0.01654578437526753
# differential_evolution step 733: f(x)= 0.01654578437526753
# differential_evolution step 734: f(x)= 0.01654578437526753
# differential_evolution step 735: f(x)= 0.01654578437526753
# differential_evolution step 736: f(x)= 0.01654578437526753
# differential_evolution step 737: f(x)= 0.01654578437526753
# differential_evolution step 738: f(x)= 0.01654578437526753
# differential_evolution step 739: f(x)= 0.015370833589103496
# differential_evolution step 740: f(x)= 0.015370833589103496
# differential_evolution step 741: f(x)= 0.015370833589103496
# differential_evolution step 742: f(x)= 0.015370833589103496
# differential_evolution step 743: f(x)= 0.015370833589103496
# differential_evolution step 744: f(x)= 0.015370833589103496
# differential_evolution step 745: f(x)= 0.015370833589103496
# differential_evolution step 746: f(x)= 0.015370833589103496
# differential_evolution step 747: f(x)= 0.015370833589103496
# differential_evolution step 748: f(x)= 0.015370833589103496
# differential_evolution step 749: f(x)= 0.015370833589103496
# differential_evolution step 750: f(x)= 0.015370833589103496
# differential_evolution step 751: f(x)= 0.015370833589103496
# differential_evolution step 752: f(x)= 0.015370833589103496
# differential_evolution step 753: f(x)= 0.015370833589103496
# differential_evolution step 754: f(x)= 0.015370833589103496
# differential_evolution step 755: f(x)= 0.015370833589103496
# differential_evolution step 756: f(x)= 0.015370833589103496
# differential_evolution step 757: f(x)= 0.015370833589103496
# differential_evolution step 758: f(x)= 0.015370833589103496
# differential_evolution step 759: f(x)= 0.015370833589103496
# differential_evolution step 760: f(x)= 0.015370833589103496
# differential_evolution step 761: f(x)= 0.015370833589103496
# differential_evolution step 762: f(x)= 0.015370833589103496
# differential_evolution step 763: f(x)= 0.015370833589103496
# differential_evolution step 764: f(x)= 0.015370833589103496
# differential_evolution step 765: f(x)= 0.015370833589103496
# differential_evolution step 766: f(x)= 0.015370833589103496
# differential_evolution step 767: f(x)= 0.015370833589103496
# differential_evolution step 768: f(x)= 0.015370833589103496
# differential_evolution step 769: f(x)= 0.015370833589103496
# differential_evolution step 770: f(x)= 0.015370833589103496
# differential_evolution step 771: f(x)= 0.015370833589103496
# differential_evolution step 772: f(x)= 0.015370833589103496
# differential_evolution step 773: f(x)= 0.015370833589103496
# differential_evolution step 774: f(x)= 0.015370833589103496
# differential_evolution step 775: f(x)= 0.015340021284564156
# differential_evolution step 776: f(x)= 0.015340021284564156
# differential_evolution step 777: f(x)= 0.015340021284564156
# differential_evolution step 778: f(x)= 0.015340021284564156
# differential_evolution step 779: f(x)= 0.015340021284564156
# differential_evolution step 780: f(x)= 0.015340021284564156
# differential_evolution step 781: f(x)= 0.015340021284564156
# differential_evolution step 782: f(x)= 0.015340021284564156
# differential_evolution step 783: f(x)= 0.015340021284564156
# differential_evolution step 784: f(x)= 0.015340021284564156
# differential_evolution step 785: f(x)= 0.015340021284564156
# differential_evolution step 786: f(x)= 0.015340021284564156
# differential_evolution step 787: f(x)= 0.015340021284564156
# differential_evolution step 788: f(x)= 0.015340021284564156
# differential_evolution step 789: f(x)= 0.015340021284564156
# differential_evolution step 790: f(x)= 0.015340021284564156
# differential_evolution step 791: f(x)= 0.015340021284564156
# differential_evolution step 792: f(x)= 0.015340021284564156
# differential_evolution step 793: f(x)= 0.015340021284564156
# differential_evolution step 794: f(x)= 0.015340021284564156
# differential_evolution step 795: f(x)= 0.015340021284564156
# differential_evolution step 796: f(x)= 0.015340021284564156
# differential_evolution step 797: f(x)= 0.015340021284564156
# differential_evolution step 798: f(x)= 0.015340021284564156
# differential_evolution step 799: f(x)= 0.015340021284564156
# differential_evolution step 800: f(x)= 0.015340021284564156
# differential_evolution step 801: f(x)= 0.015340021284564156
# differential_evolution step 802: f(x)= 0.015340021284564156
# differential_evolution step 803: f(x)= 0.015340021284564156
# differential_evolution step 804: f(x)= 0.015340021284564156
# differential_evolution step 805: f(x)= 0.01382539350065987
# differential_evolution step 806: f(x)= 0.01382539350065987
# differential_evolution step 807: f(x)= 0.01382539350065987
# differential_evolution step 808: f(x)= 0.01382539350065987
# differential_evolution step 809: f(x)= 0.012522519891198413
# differential_evolution step 810: f(x)= 0.012522519891198413
# differential_evolution step 811: f(x)= 0.012522519891198413
# differential_evolution step 812: f(x)= 0.012522519891198413
# differential_evolution step 813: f(x)= 0.012522519891198413
# differential_evolution step 814: f(x)= 0.012522519891198413
# differential_evolution step 815: f(x)= 0.012522519891198413
# differential_evolution step 816: f(x)= 0.012522519891198413
# differential_evolution step 817: f(x)= 0.012522519891198413
# differential_evolution step 818: f(x)= 0.012522519891198413
# differential_evolution step 819: f(x)= 0.012397465528267919
# differential_evolution step 820: f(x)= 0.012397465528267919
# differential_evolution step 821: f(x)= 0.012397465528267919
# differential_evolution step 822: f(x)= 0.012397465528267919
# differential_evolution step 823: f(x)= 0.012397465528267919
# differential_evolution step 824: f(x)= 0.012397465528267919
# differential_evolution step 825: f(x)= 0.012397465528267919
# differential_evolution step 826: f(x)= 0.012397465528267919
# differential_evolution step 827: f(x)= 0.012397465528267919
# differential_evolution step 828: f(x)= 0.012397465528267919
# differential_evolution step 829: f(x)= 0.012397465528267919
# differential_evolution step 830: f(x)= 0.012397465528267919
# differential_evolution step 831: f(x)= 0.012397465528267919
# differential_evolution step 832: f(x)= 0.012397465528267919
# differential_evolution step 833: f(x)= 0.012397465528267919
# differential_evolution step 834: f(x)= 0.012397465528267919
# differential_evolution step 835: f(x)= 0.012397465528267919
# differential_evolution step 836: f(x)= 0.012397465528267919
# differential_evolution step 837: f(x)= 0.012397465528267919
# differential_evolution step 838: f(x)= 0.012397465528267919
# differential_evolution step 839: f(x)= 0.012397465528267919
# differential_evolution step 840: f(x)= 0.012397465528267919
# differential_evolution step 841: f(x)= 0.012397465528267919
# differential_evolution step 842: f(x)= 0.012397465528267919
# differential_evolution step 843: f(x)= 0.012397465528267919
# differential_evolution step 844: f(x)= 0.012397465528267919
# differential_evolution step 845: f(x)= 0.012397465528267919
# differential_evolution step 846: f(x)= 0.012397465528267919
# differential_evolution step 847: f(x)= 0.012397465528267919
# differential_evolution step 848: f(x)= 0.012397465528267919
# differential_evolution step 849: f(x)= 0.012397465528267919
# differential_evolution step 850: f(x)= 0.012397465528267919
# differential_evolution step 851: f(x)= 0.012397465528267919
# differential_evolution step 852: f(x)= 0.012397465528267919
# differential_evolution step 853: f(x)= 0.012397465528267919
# differential_evolution step 854: f(x)= 0.012397465528267919
# differential_evolution step 855: f(x)= 0.012397465528267919
# differential_evolution step 856: f(x)= 0.012397465528267919
# differential_evolution step 857: f(x)= 0.012397465528267919
# differential_evolution step 858: f(x)= 0.012397465528267919
# differential_evolution step 859: f(x)= 0.012397465528267919
# differential_evolution step 860: f(x)= 0.012397465528267919
# differential_evolution step 861: f(x)= 0.012397465528267919
# differential_evolution step 862: f(x)= 0.012397465528267919
# differential_evolution step 863: f(x)= 0.012397465528267919
# differential_evolution step 864: f(x)= 0.012397465528267919
# differential_evolution step 865: f(x)= 0.012397465528267919
# differential_evolution step 866: f(x)= 0.012397465528267919
# differential_evolution step 867: f(x)= 0.012397465528267919
# differential_evolution step 868: f(x)= 0.012397465528267919
# differential_evolution step 869: f(x)= 0.012397465528267919
# differential_evolution step 870: f(x)= 0.012397465528267919
# differential_evolution step 871: f(x)= 0.012397465528267919
# differential_evolution step 872: f(x)= 0.012397465528267919
# differential_evolution step 873: f(x)= 0.012397465528267919
# differential_evolution step 874: f(x)= 0.012397465528267919
# differential_evolution step 875: f(x)= 0.012397465528267919
# differential_evolution step 876: f(x)= 0.012397465528267919
# differential_evolution step 877: f(x)= 0.012397465528267919
# differential_evolution step 878: f(x)= 0.012397465528267919
# differential_evolution step 879: f(x)= 0.012397465528267919
# differential_evolution step 880: f(x)= 0.012397465528267919
# differential_evolution step 881: f(x)= 0.012397465528267919
# differential_evolution step 882: f(x)= 0.012397465528267919
# differential_evolution step 883: f(x)= 0.012397465528267919
# differential_evolution step 884: f(x)= 0.012397465528267919
# differential_evolution step 885: f(x)= 0.012397465528267919
# differential_evolution step 886: f(x)= 0.012397465528267919
# differential_evolution step 887: f(x)= 0.012397465528267919
# differential_evolution step 888: f(x)= 0.012397465528267919
# differential_evolution step 889: f(x)= 0.012397465528267919
# differential_evolution step 890: f(x)= 0.012397465528267919
# differential_evolution step 891: f(x)= 0.012397465528267919
# differential_evolution step 892: f(x)= 0.012397465528267919
# differential_evolution step 893: f(x)= 0.012397465528267919
# differential_evolution step 894: f(x)= 0.012397465528267919
# differential_evolution step 895: f(x)= 0.012397465528267919
# differential_evolution step 896: f(x)= 0.012397465528267919
# differential_evolution step 897: f(x)= 0.012397465528267919
# differential_evolution step 898: f(x)= 0.012397465528267919
# differential_evolution step 899: f(x)= 0.012397465528267919
# differential_evolution step 900: f(x)= 0.012160387288699748
# differential_evolution step 901: f(x)= 0.012160387288699748
# differential_evolution step 902: f(x)= 0.012160387288699748
# differential_evolution step 903: f(x)= 0.012160387288699748
# differential_evolution step 904: f(x)= 0.012160387288699748
# differential_evolution step 905: f(x)= 0.012160387288699748
# differential_evolution step 906: f(x)= 0.012160387288699748
# differential_evolution step 907: f(x)= 0.012160387288699748
# differential_evolution step 908: f(x)= 0.012160387288699748
# differential_evolution step 909: f(x)= 0.012160387288699748
# differential_evolution step 910: f(x)= 0.012160387288699748
# differential_evolution step 911: f(x)= 0.012160387288699748
# differential_evolution step 912: f(x)= 0.012160387288699748
# differential_evolution step 913: f(x)= 0.012160387288699748
# differential_evolution step 914: f(x)= 0.012160387288699748
# differential_evolution step 915: f(x)= 0.012160387288699748
# differential_evolution step 916: f(x)= 0.012160387288699748
# differential_evolution step 917: f(x)= 0.012160387288699748
# differential_evolution step 918: f(x)= 0.012160387288699748
# differential_evolution step 919: f(x)= 0.012160387288699748
# differential_evolution step 920: f(x)= 0.012160387288699748
# differential_evolution step 921: f(x)= 0.012160387288699748
# differential_evolution step 922: f(x)= 0.012160387288699748
# differential_evolution step 923: f(x)= 0.012160387288699748
# differential_evolution step 924: f(x)= 0.012160387288699748
# differential_evolution step 925: f(x)= 0.012160387288699748
# differential_evolution step 926: f(x)= 0.012160387288699748
# differential_evolution step 927: f(x)= 0.012160387288699748
# differential_evolution step 928: f(x)= 0.012160387288699748
# differential_evolution step 929: f(x)= 0.012160387288699748
# differential_evolution step 930: f(x)= 0.012160387288699748
# differential_evolution step 931: f(x)= 0.012160387288699748
# differential_evolution step 932: f(x)= 0.012160387288699748
# differential_evolution step 933: f(x)= 0.012160387288699748
# differential_evolution step 934: f(x)= 0.012160387288699748
# differential_evolution step 935: f(x)= 0.012160387288699748
# differential_evolution step 936: f(x)= 0.012160387288699748
# differential_evolution step 937: f(x)= 0.011644906192382044
# differential_evolution step 938: f(x)= 0.011644906192382044
# differential_evolution step 939: f(x)= 0.011644906192382044
# differential_evolution step 940: f(x)= 0.011644906192382044
# differential_evolution step 941: f(x)= 0.011644906192382044
# differential_evolution step 942: f(x)= 0.011644906192382044
# differential_evolution step 943: f(x)= 0.011644906192382044
# differential_evolution step 944: f(x)= 0.011644906192382044
# differential_evolution step 945: f(x)= 0.011644906192382044
# differential_evolution step 946: f(x)= 0.011644906192382044
# differential_evolution step 947: f(x)= 0.011644906192382044
# differential_evolution step 948: f(x)= 0.011644906192382044
# differential_evolution step 949: f(x)= 0.011644906192382044
# differential_evolution step 950: f(x)= 0.011644906192382044
# differential_evolution step 951: f(x)= 0.011644906192382044
# differential_evolution step 952: f(x)= 0.011644906192382044
# differential_evolution step 953: f(x)= 0.011644906192382044
# differential_evolution step 954: f(x)= 0.011644906192382044
# differential_evolution step 955: f(x)= 0.011644906192382044
# differential_evolution step 956: f(x)= 0.011644906192382044
# differential_evolution step 957: f(x)= 0.011644906192382044
# differential_evolution step 958: f(x)= 0.011644906192382044
# differential_evolution step 959: f(x)= 0.011644906192382044
# differential_evolution step 960: f(x)= 0.011644906192382044
# differential_evolution step 961: f(x)= 0.011644906192382044
# differential_evolution step 962: f(x)= 0.011644906192382044
# differential_evolution step 963: f(x)= 0.011644906192382044
# differential_evolution step 964: f(x)= 0.011644906192382044
# differential_evolution step 965: f(x)= 0.011644906192382044
# differential_evolution step 966: f(x)= 0.011644906192382044
# differential_evolution step 967: f(x)= 0.011644906192382044
# differential_evolution step 968: f(x)= 0.011644906192382044
# differential_evolution step 969: f(x)= 0.011644906192382044
# differential_evolution step 970: f(x)= 0.011644906192382044
# differential_evolution step 971: f(x)= 0.011644906192382044
# differential_evolution step 972: f(x)= 0.011644906192382044
# differential_evolution step 973: f(x)= 0.011644906192382044
# differential_evolution step 974: f(x)= 0.011644906192382044
# differential_evolution step 975: f(x)= 0.011644906192382044
# differential_evolution step 976: f(x)= 0.011526340853774266
# differential_evolution step 977: f(x)= 0.011526340853774266
# differential_evolution step 978: f(x)= 0.011526340853774266
# differential_evolution step 979: f(x)= 0.011526340853774266
# differential_evolution step 980: f(x)= 0.011526340853774266
# differential_evolution step 981: f(x)= 0.011526340853774266
# differential_evolution step 982: f(x)= 0.011526340853774266
# differential_evolution step 983: f(x)= 0.011526340853774266
# differential_evolution step 984: f(x)= 0.011526340853774266
# differential_evolution step 985: f(x)= 0.011526340853774266
# differential_evolution step 986: f(x)= 0.011526340853774266
# differential_evolution step 987: f(x)= 0.011526340853774266
# differential_evolution step 988: f(x)= 0.011526340853774266
# differential_evolution step 989: f(x)= 0.011526340853774266
# differential_evolution step 990: f(x)= 0.011526340853774266
# differential_evolution step 991: f(x)= 0.011526340853774266
# differential_evolution step 992: f(x)= 0.011526340853774266
# differential_evolution step 993: f(x)= 0.011526340853774266
# differential_evolution step 994: f(x)= 0.011526340853774266
# differential_evolution step 995: f(x)= 0.011526340853774266
# differential_evolution step 996: f(x)= 0.01105023253788731
# differential_evolution step 997: f(x)= 0.01105023253788731
# differential_evolution step 998: f(x)= 0.01105023253788731
# differential_evolution step 999: f(x)= 0.01105023253788731
# differential_evolution step 1000: f(x)= 0.01105023253788731
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.3649, r_e=4.0803, n=0.7970, x_0=26.8791
# Sérsic 2: I_e=0.0496, r_e=40.5378, n=1.1230, x_0=47.9840
# Sérsic 3: I_e=2.0104, r_e=0.3445, n=1.2640, x_0=61.2424
# Sérsic 4: I_e=0.0368, r_e=11.5921, n=1.5557, x_0=68.2933
# Sérsic 5: I_e=0.0232, r_e=12.7856, n=1.0152, x_0=102.7573
# Chi quadro minimo: 0.010278408079333666
# False

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha_diff", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=0.3649, r_e=4.0803, n=0.7970, x_0=26.8791
# Sérsic 2: I_e=0.0496, r_e=40.5378, n=1.1230, x_0=47.9840
# Sérsic 3: I_e=2.0104, r_e=0.3445, n=1.2640, x_0=61.2424
# Sérsic 4: I_e=0.0368, r_e=11.5921, n=1.5557, x_0=68.2933
# Sérsic 5: I_e=0.0232, r_e=12.7856, n=1.0152, x_0=102.7573
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA, bounds = bounds_list, maxfev= 10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.3774, r_e=4.0326, n=0.7668, x_0=26.8832
# Sérsic 2: I_e=0.0476, r_e=41.5138, n=1.1484, x_0=48.0000
# Sérsic 3: I_e=0.4483, r_e=0.6801, n=2.6027, x_0=61.2406
# Sérsic 4: I_e=0.0352, r_e=10.6559, n=1.6220, x_0=68.3231
# Sérsic 5: I_e=0.0064, r_e=37.7483, n=1.8322, x_0=102.8055
# [2.50969908e-02 1.53574797e-01 5.40246091e-02 2.89497241e-02
#  7.01315757e-03 3.86652206e+00 8.69686991e-02 3.26121888e-01
#  3.94992081e+00 2.20947008e+00 8.78460367e+00 3.29481415e-02
#  2.06337888e-02 4.42396901e+00 5.21891541e-01 1.62711403e-01
#  7.50380228e-03 4.10392560e+01 7.52381219e-01 2.78903014e-01]
# 0.07601677476688395

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-seeing[-1]/2, x_0_HA[0]+seeing[-1]/2),   # x_0: posizione da 0 a 100

    (0, 10),
    (5, 20),
    (0.1, 10),
    (x_0_HA[1]-seeing[-1]/2, x_0_HA[1]+seeing[-1]/2),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[2]-seeing[-1]/2, x_0_HA[2]+seeing[-1]/2),   # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 20),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[3]-seeing[-1]/2, x_0_HA[3]+seeing[-1]/2),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 20),
    (0.1, 10),
    (x_0_HA[4]-seeing[-1]/2, x_0_HA[4]+seeing[-1]/2),
]

bounds_OIII = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (20, 30),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (5, 20),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (45, 48),   # x_0: posizione da 0 a 100

     (0, 10),
    (0, 50),
    (0.1, 10),
    (59, 65),
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 20),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 70),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 10),
    (0.1, 10),
    (102, 103),
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))
real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[2])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 120, 1)
plt.plot(x_axes, radial_profile_HB, label ='Hbeta')
plt.plot(x_axes, radial_profile_HA, label = 'Halpha')
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_OIII

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 45401.21987087505
# differential_evolution step 2: f(x)= 5043.039230312329
# differential_evolution step 3: f(x)= 5043.039230312329
# differential_evolution step 4: f(x)= 5043.039230312329
# differential_evolution step 5: f(x)= 5043.039230312329
# differential_evolution step 6: f(x)= 3280.6024935473934
# differential_evolution step 7: f(x)= 373.9590877463109
# differential_evolution step 8: f(x)= 373.9590877463109
# differential_evolution step 9: f(x)= 373.9590877463109
# differential_evolution step 10: f(x)= 373.9590877463109
# differential_evolution step 11: f(x)= 373.9590877463109
# differential_evolution step 12: f(x)= 373.9590877463109
# differential_evolution step 13: f(x)= 338.3331372237342
# differential_evolution step 14: f(x)= 338.3331372237342
# differential_evolution step 15: f(x)= 338.3331372237342
# differential_evolution step 16: f(x)= 338.3331372237342
# differential_evolution step 17: f(x)= 338.3331372237342
# differential_evolution step 18: f(x)= 118.8130965363091
# differential_evolution step 19: f(x)= 118.8130965363091
# differential_evolution step 20: f(x)= 118.8130965363091
# differential_evolution step 21: f(x)= 118.8130965363091
# differential_evolution step 22: f(x)= 118.8130965363091
# differential_evolution step 23: f(x)= 118.8130965363091
# differential_evolution step 24: f(x)= 118.8130965363091
# differential_evolution step 25: f(x)= 61.83892932045987
# differential_evolution step 26: f(x)= 61.83892932045987
# differential_evolution step 27: f(x)= 61.83892932045987
# differential_evolution step 28: f(x)= 61.83892932045987
# differential_evolution step 29: f(x)= 61.83892932045987
# differential_evolution step 30: f(x)= 61.83892932045987
# differential_evolution step 31: f(x)= 61.83892932045987
# differential_evolution step 32: f(x)= 61.83892932045987
# differential_evolution step 33: f(x)= 61.83892932045987
# differential_evolution step 34: f(x)= 61.45422381238953
# differential_evolution step 35: f(x)= 61.45422381238953
# differential_evolution step 36: f(x)= 61.45422381238953
# differential_evolution step 37: f(x)= 60.28882378049687
# differential_evolution step 38: f(x)= 42.331212127511606
# differential_evolution step 39: f(x)= 42.331212127511606
# differential_evolution step 40: f(x)= 42.331212127511606
# differential_evolution step 41: f(x)= 42.331212127511606
# differential_evolution step 42: f(x)= 42.331212127511606
# differential_evolution step 43: f(x)= 42.331212127511606
# differential_evolution step 44: f(x)= 42.331212127511606
# differential_evolution step 45: f(x)= 37.84371852097236
# differential_evolution step 46: f(x)= 37.84371852097236
# differential_evolution step 47: f(x)= 37.84371852097236
# differential_evolution step 48: f(x)= 12.509792385194492
# differential_evolution step 49: f(x)= 12.509792385194492
# differential_evolution step 50: f(x)= 12.509792385194492
# differential_evolution step 51: f(x)= 9.47045612505781
# differential_evolution step 52: f(x)= 9.219775950953554
# differential_evolution step 53: f(x)= 9.219775950953554
# differential_evolution step 54: f(x)= 9.219775950953554
# differential_evolution step 55: f(x)= 4.756677103844335
# differential_evolution step 56: f(x)= 4.756677103844335
# differential_evolution step 57: f(x)= 4.756677103844335
# differential_evolution step 58: f(x)= 4.756677103844335
# differential_evolution step 59: f(x)= 4.756677103844335
# differential_evolution step 60: f(x)= 4.756677103844335
# differential_evolution step 61: f(x)= 4.756677103844335
# differential_evolution step 62: f(x)= 4.756677103844335
# differential_evolution step 63: f(x)= 1.833204634685726
# differential_evolution step 64: f(x)= 1.833204634685726
# differential_evolution step 65: f(x)= 1.833204634685726
# differential_evolution step 66: f(x)= 1.833204634685726
# differential_evolution step 67: f(x)= 1.833204634685726
# differential_evolution step 68: f(x)= 1.833204634685726
# differential_evolution step 69: f(x)= 1.833204634685726
# differential_evolution step 70: f(x)= 1.833204634685726
# differential_evolution step 71: f(x)= 1.833204634685726
# differential_evolution step 72: f(x)= 1.833204634685726
# differential_evolution step 73: f(x)= 1.833204634685726
# differential_evolution step 74: f(x)= 1.833204634685726
# differential_evolution step 75: f(x)= 1.833204634685726
# differential_evolution step 76: f(x)= 1.833204634685726
# differential_evolution step 77: f(x)= 1.833204634685726
# differential_evolution step 78: f(x)= 1.833204634685726
# differential_evolution step 79: f(x)= 1.833204634685726
# differential_evolution step 80: f(x)= 1.833204634685726
# differential_evolution step 81: f(x)= 1.833204634685726
# differential_evolution step 82: f(x)= 1.833204634685726
# differential_evolution step 83: f(x)= 1.833204634685726
# differential_evolution step 84: f(x)= 1.833204634685726
# differential_evolution step 85: f(x)= 1.833204634685726
# differential_evolution step 86: f(x)= 1.271530662468959
# differential_evolution step 87: f(x)= 1.271530662468959
# differential_evolution step 88: f(x)= 1.271530662468959
# differential_evolution step 89: f(x)= 1.271530662468959
# differential_evolution step 90: f(x)= 1.271530662468959
# differential_evolution step 91: f(x)= 1.271530662468959
# differential_evolution step 92: f(x)= 1.271530662468959
# differential_evolution step 93: f(x)= 1.271530662468959
# differential_evolution step 94: f(x)= 1.271530662468959
# differential_evolution step 95: f(x)= 1.271530662468959
# differential_evolution step 96: f(x)= 1.271530662468959
# differential_evolution step 97: f(x)= 1.271530662468959
# differential_evolution step 98: f(x)= 0.9762966415859528
# differential_evolution step 99: f(x)= 0.9762966415859528
# differential_evolution step 100: f(x)= 0.9762966415859528
# differential_evolution step 101: f(x)= 0.9762966415859528
# differential_evolution step 102: f(x)= 0.9762966415859528
# differential_evolution step 103: f(x)= 0.9762966415859528
# differential_evolution step 104: f(x)= 0.9762966415859528
# differential_evolution step 105: f(x)= 0.9762966415859528
# differential_evolution step 106: f(x)= 0.8985145696950001
# differential_evolution step 107: f(x)= 0.8985145696950001
# differential_evolution step 108: f(x)= 0.8985145696950001
# differential_evolution step 109: f(x)= 0.8985145696950001
# differential_evolution step 110: f(x)= 0.8985145696950001
# differential_evolution step 111: f(x)= 0.8985145696950001
# differential_evolution step 112: f(x)= 0.8985145696950001
# differential_evolution step 113: f(x)= 0.5232777479594454
# differential_evolution step 114: f(x)= 0.5232777479594454
# differential_evolution step 115: f(x)= 0.5232777479594454
# differential_evolution step 116: f(x)= 0.5232777479594454
# differential_evolution step 117: f(x)= 0.5232777479594454
# differential_evolution step 118: f(x)= 0.5232777479594454
# differential_evolution step 119: f(x)= 0.5232777479594454
# differential_evolution step 120: f(x)= 0.5232777479594454
# differential_evolution step 121: f(x)= 0.5232777479594454
# differential_evolution step 122: f(x)= 0.5232777479594454
# differential_evolution step 123: f(x)= 0.5232777479594454
# differential_evolution step 124: f(x)= 0.468848899415278
# differential_evolution step 125: f(x)= 0.468848899415278
# differential_evolution step 126: f(x)= 0.468848899415278
# differential_evolution step 127: f(x)= 0.468848899415278
# differential_evolution step 128: f(x)= 0.468848899415278
# differential_evolution step 129: f(x)= 0.468848899415278
# differential_evolution step 130: f(x)= 0.468848899415278
# differential_evolution step 131: f(x)= 0.468848899415278
# differential_evolution step 132: f(x)= 0.468848899415278
# differential_evolution step 133: f(x)= 0.468848899415278
# differential_evolution step 134: f(x)= 0.4511868347484437
# differential_evolution step 135: f(x)= 0.4511868347484437
# differential_evolution step 136: f(x)= 0.4511868347484437
# differential_evolution step 137: f(x)= 0.4511868347484437
# differential_evolution step 138: f(x)= 0.4511868347484437
# differential_evolution step 139: f(x)= 0.4511868347484437
# differential_evolution step 140: f(x)= 0.4511868347484437
# differential_evolution step 141: f(x)= 0.4511868347484437
# differential_evolution step 142: f(x)= 0.4000159976459039
# differential_evolution step 143: f(x)= 0.4000159976459039
# differential_evolution step 144: f(x)= 0.4000159976459039
# differential_evolution step 145: f(x)= 0.3788335658765647
# differential_evolution step 146: f(x)= 0.35480610967393866
# differential_evolution step 147: f(x)= 0.35480610967393866
# differential_evolution step 148: f(x)= 0.35480610967393866
# differential_evolution step 149: f(x)= 0.35480610967393866
# differential_evolution step 150: f(x)= 0.35480610967393866
# differential_evolution step 151: f(x)= 0.35480610967393866
# differential_evolution step 152: f(x)= 0.35480610967393866
# differential_evolution step 153: f(x)= 0.35480610967393866
# differential_evolution step 154: f(x)= 0.35480610967393866
# differential_evolution step 155: f(x)= 0.35480610967393866
# differential_evolution step 156: f(x)= 0.35480610967393866
# differential_evolution step 157: f(x)= 0.35480610967393866
# differential_evolution step 158: f(x)= 0.35480610967393866
# differential_evolution step 159: f(x)= 0.35480610967393866
# differential_evolution step 160: f(x)= 0.35480610967393866
# differential_evolution step 161: f(x)= 0.35480610967393866
# differential_evolution step 162: f(x)= 0.35480610967393866
# differential_evolution step 163: f(x)= 0.35480610967393866
# differential_evolution step 164: f(x)= 0.3057556419094178
# differential_evolution step 165: f(x)= 0.3057556419094178
# differential_evolution step 166: f(x)= 0.3057556419094178
# differential_evolution step 167: f(x)= 0.3057556419094178
# differential_evolution step 168: f(x)= 0.27274190054299574
# differential_evolution step 169: f(x)= 0.27274190054299574
# differential_evolution step 170: f(x)= 0.27274190054299574
# differential_evolution step 171: f(x)= 0.27274190054299574
# differential_evolution step 172: f(x)= 0.27274190054299574
# differential_evolution step 173: f(x)= 0.2664076085124698
# differential_evolution step 174: f(x)= 0.2664076085124698
# differential_evolution step 175: f(x)= 0.2664076085124698
# differential_evolution step 176: f(x)= 0.2664076085124698
# differential_evolution step 177: f(x)= 0.2664076085124698
# differential_evolution step 178: f(x)= 0.2664076085124698
# differential_evolution step 179: f(x)= 0.2664076085124698
# differential_evolution step 180: f(x)= 0.2664076085124698
# differential_evolution step 181: f(x)= 0.21349018251815893
# differential_evolution step 182: f(x)= 0.21349018251815893
# differential_evolution step 183: f(x)= 0.19414524930755594
# differential_evolution step 184: f(x)= 0.19414524930755594
# differential_evolution step 185: f(x)= 0.19414524930755594
# differential_evolution step 186: f(x)= 0.19414524930755594
# differential_evolution step 187: f(x)= 0.18542420177038316
# differential_evolution step 188: f(x)= 0.18542420177038316
# differential_evolution step 189: f(x)= 0.18542420177038316
# differential_evolution step 190: f(x)= 0.16032101028042217
# differential_evolution step 191: f(x)= 0.16032101028042217
# differential_evolution step 192: f(x)= 0.16032101028042217
# differential_evolution step 193: f(x)= 0.16032101028042217
# differential_evolution step 194: f(x)= 0.16032101028042217
# differential_evolution step 195: f(x)= 0.16032101028042217
# differential_evolution step 196: f(x)= 0.16032101028042217
# differential_evolution step 197: f(x)= 0.16032101028042217
# differential_evolution step 198: f(x)= 0.15580214850717555
# differential_evolution step 199: f(x)= 0.1468700056417115
# differential_evolution step 200: f(x)= 0.13695266347014634
# differential_evolution step 201: f(x)= 0.13695266347014634
# differential_evolution step 202: f(x)= 0.13695266347014634
# differential_evolution step 203: f(x)= 0.13695266347014634
# differential_evolution step 204: f(x)= 0.13695266347014634
# differential_evolution step 205: f(x)= 0.13695266347014634
# differential_evolution step 206: f(x)= 0.13695266347014634
# differential_evolution step 207: f(x)= 0.13695266347014634
# differential_evolution step 208: f(x)= 0.13695266347014634
# differential_evolution step 209: f(x)= 0.13695266347014634
# differential_evolution step 210: f(x)= 0.13695266347014634
# differential_evolution step 211: f(x)= 0.13695266347014634
# differential_evolution step 212: f(x)= 0.12445935204712039
# differential_evolution step 213: f(x)= 0.12445935204712039
# differential_evolution step 214: f(x)= 0.12445935204712039
# differential_evolution step 215: f(x)= 0.12445935204712039
# differential_evolution step 216: f(x)= 0.12278350021068639
# differential_evolution step 217: f(x)= 0.12278350021068639
# differential_evolution step 218: f(x)= 0.11454817135253378
# differential_evolution step 219: f(x)= 0.11454817135253378
# differential_evolution step 220: f(x)= 0.11454817135253378
# differential_evolution step 221: f(x)= 0.11454817135253378
# differential_evolution step 222: f(x)= 0.11454817135253378
# differential_evolution step 223: f(x)= 0.11454817135253378
# differential_evolution step 224: f(x)= 0.11454817135253378
# differential_evolution step 225: f(x)= 0.11454817135253378
# differential_evolution step 226: f(x)= 0.11454817135253378
# differential_evolution step 227: f(x)= 0.11454817135253378
# differential_evolution step 228: f(x)= 0.11454817135253378
# differential_evolution step 229: f(x)= 0.11248260818468875
# differential_evolution step 230: f(x)= 0.11248260818468875
# differential_evolution step 231: f(x)= 0.11248260818468875
# differential_evolution step 232: f(x)= 0.11248260818468875
# differential_evolution step 233: f(x)= 0.11248260818468875
# differential_evolution step 234: f(x)= 0.11248260818468875
# differential_evolution step 235: f(x)= 0.11248260818468875
# differential_evolution step 236: f(x)= 0.11248260818468875
# differential_evolution step 237: f(x)= 0.10911675258240748
# differential_evolution step 238: f(x)= 0.10911675258240748
# differential_evolution step 239: f(x)= 0.10911675258240748
# differential_evolution step 240: f(x)= 0.10911675258240748
# differential_evolution step 241: f(x)= 0.09940701552159052
# differential_evolution step 242: f(x)= 0.09940701552159052
# differential_evolution step 243: f(x)= 0.09940701552159052
# differential_evolution step 244: f(x)= 0.09940701552159052
# differential_evolution step 245: f(x)= 0.09940701552159052
# differential_evolution step 246: f(x)= 0.09940701552159052
# differential_evolution step 247: f(x)= 0.09940701552159052
# differential_evolution step 248: f(x)= 0.09940701552159052
# differential_evolution step 249: f(x)= 0.09757806436095975
# differential_evolution step 250: f(x)= 0.09601090818624916
# differential_evolution step 251: f(x)= 0.09601090818624916
# differential_evolution step 252: f(x)= 0.09601090818624916
# differential_evolution step 253: f(x)= 0.09601090818624916
# differential_evolution step 254: f(x)= 0.09373643165477508
# differential_evolution step 255: f(x)= 0.09373643165477508
# differential_evolution step 256: f(x)= 0.09373643165477508
# differential_evolution step 257: f(x)= 0.09373643165477508
# differential_evolution step 258: f(x)= 0.09373643165477508
# differential_evolution step 259: f(x)= 0.09373643165477508
# differential_evolution step 260: f(x)= 0.09360874739667092
# differential_evolution step 261: f(x)= 0.09360874739667092
# differential_evolution step 262: f(x)= 0.09360874739667092
# differential_evolution step 263: f(x)= 0.09360874739667092
# differential_evolution step 264: f(x)= 0.09360874739667092
# differential_evolution step 265: f(x)= 0.08705922548071293
# differential_evolution step 266: f(x)= 0.08705922548071293
# differential_evolution step 267: f(x)= 0.08705922548071293
# differential_evolution step 268: f(x)= 0.08705922548071293
# differential_evolution step 269: f(x)= 0.083874341904737
# differential_evolution step 270: f(x)= 0.083874341904737
# differential_evolution step 271: f(x)= 0.083874341904737
# differential_evolution step 272: f(x)= 0.083874341904737
# differential_evolution step 273: f(x)= 0.083874341904737
# differential_evolution step 274: f(x)= 0.083874341904737
# differential_evolution step 275: f(x)= 0.083874341904737
# differential_evolution step 276: f(x)= 0.0826886871656794
# differential_evolution step 277: f(x)= 0.0826886871656794
# differential_evolution step 278: f(x)= 0.08147026674984964
# differential_evolution step 279: f(x)= 0.08147026674984964
# differential_evolution step 280: f(x)= 0.08147026674984964
# differential_evolution step 281: f(x)= 0.08147026674984964
# differential_evolution step 282: f(x)= 0.08147026674984964
# differential_evolution step 283: f(x)= 0.08147026674984964
# differential_evolution step 284: f(x)= 0.08147026674984964
# differential_evolution step 285: f(x)= 0.07796675973859597
# differential_evolution step 286: f(x)= 0.07796675973859597
# differential_evolution step 287: f(x)= 0.07796675973859597
# differential_evolution step 288: f(x)= 0.07796675973859597
# differential_evolution step 289: f(x)= 0.07796675973859597
# differential_evolution step 290: f(x)= 0.07796675973859597
# differential_evolution step 291: f(x)= 0.07796675973859597
# differential_evolution step 292: f(x)= 0.07796675973859597
# differential_evolution step 293: f(x)= 0.07796675973859597
# differential_evolution step 294: f(x)= 0.07796675973859597
# differential_evolution step 295: f(x)= 0.07796675973859597
# differential_evolution step 296: f(x)= 0.07796675973859597
# differential_evolution step 297: f(x)= 0.07796675973859597
# differential_evolution step 298: f(x)= 0.07796675973859597
# differential_evolution step 299: f(x)= 0.07796675973859597
# differential_evolution step 300: f(x)= 0.07796675973859597
# differential_evolution step 301: f(x)= 0.07796675973859597
# differential_evolution step 302: f(x)= 0.07796675973859597
# differential_evolution step 303: f(x)= 0.07796675973859597
# differential_evolution step 304: f(x)= 0.07796675973859597
# differential_evolution step 305: f(x)= 0.07796675973859597
# differential_evolution step 306: f(x)= 0.07796675973859597
# differential_evolution step 307: f(x)= 0.074326665783946
# differential_evolution step 308: f(x)= 0.074326665783946
# differential_evolution step 309: f(x)= 0.074326665783946
# differential_evolution step 310: f(x)= 0.074326665783946
# differential_evolution step 311: f(x)= 0.074326665783946
# differential_evolution step 312: f(x)= 0.074326665783946
# differential_evolution step 313: f(x)= 0.074326665783946
# differential_evolution step 314: f(x)= 0.074326665783946
# differential_evolution step 315: f(x)= 0.074326665783946
# differential_evolution step 316: f(x)= 0.074326665783946
# differential_evolution step 317: f(x)= 0.074326665783946
# differential_evolution step 318: f(x)= 0.074326665783946
# differential_evolution step 319: f(x)= 0.074326665783946
# differential_evolution step 320: f(x)= 0.074326665783946
# differential_evolution step 321: f(x)= 0.074326665783946
# differential_evolution step 322: f(x)= 0.074326665783946
# differential_evolution step 323: f(x)= 0.074326665783946
# differential_evolution step 324: f(x)= 0.074326665783946
# differential_evolution step 325: f(x)= 0.07405377667119817
# differential_evolution step 326: f(x)= 0.07405377667119817
# differential_evolution step 327: f(x)= 0.07405377667119817
# differential_evolution step 328: f(x)= 0.07405377667119817
# differential_evolution step 329: f(x)= 0.07405377667119817
# differential_evolution step 330: f(x)= 0.07405377667119817
# differential_evolution step 331: f(x)= 0.07405377667119817
# differential_evolution step 332: f(x)= 0.07405377667119817
# differential_evolution step 333: f(x)= 0.07405377667119817
# differential_evolution step 334: f(x)= 0.07405377667119817
# differential_evolution step 335: f(x)= 0.07073790099392674
# differential_evolution step 336: f(x)= 0.07073790099392674
# differential_evolution step 337: f(x)= 0.07073790099392674
# differential_evolution step 338: f(x)= 0.07073790099392674
# differential_evolution step 339: f(x)= 0.07073790099392674
# differential_evolution step 340: f(x)= 0.07073790099392674
# differential_evolution step 341: f(x)= 0.07073790099392674
# differential_evolution step 342: f(x)= 0.07073790099392674
# differential_evolution step 343: f(x)= 0.07073790099392674
# differential_evolution step 344: f(x)= 0.07073790099392674
# differential_evolution step 345: f(x)= 0.07073790099392674
# differential_evolution step 346: f(x)= 0.07073790099392674
# differential_evolution step 347: f(x)= 0.07073790099392674
# differential_evolution step 348: f(x)= 0.07073790099392674
# differential_evolution step 349: f(x)= 0.07073790099392674
# differential_evolution step 350: f(x)= 0.07073790099392674
# differential_evolution step 351: f(x)= 0.07073790099392674
# differential_evolution step 352: f(x)= 0.07073790099392674
# differential_evolution step 353: f(x)= 0.07073790099392674
# differential_evolution step 354: f(x)= 0.07073790099392674
# differential_evolution step 355: f(x)= 0.07073790099392674
# differential_evolution step 356: f(x)= 0.07073790099392674
# differential_evolution step 357: f(x)= 0.07073790099392674
# differential_evolution step 358: f(x)= 0.07073790099392674
# differential_evolution step 359: f(x)= 0.07073790099392674
# differential_evolution step 360: f(x)= 0.07073790099392674
# differential_evolution step 361: f(x)= 0.07073790099392674
# differential_evolution step 362: f(x)= 0.07073790099392674
# differential_evolution step 363: f(x)= 0.07073790099392674
# differential_evolution step 364: f(x)= 0.07073790099392674
# differential_evolution step 365: f(x)= 0.07073790099392674
# differential_evolution step 366: f(x)= 0.07073790099392674
# differential_evolution step 367: f(x)= 0.07073790099392674
# differential_evolution step 368: f(x)= 0.07073790099392674
# differential_evolution step 369: f(x)= 0.07073790099392674
# differential_evolution step 370: f(x)= 0.07042170071527903
# differential_evolution step 371: f(x)= 0.06977463325873284
# differential_evolution step 372: f(x)= 0.06977463325873284
# differential_evolution step 373: f(x)= 0.06977463325873284
# differential_evolution step 374: f(x)= 0.06977463325873284
# differential_evolution step 375: f(x)= 0.06977463325873284
# differential_evolution step 376: f(x)= 0.06977463325873284
# differential_evolution step 377: f(x)= 0.06977463325873284
# differential_evolution step 378: f(x)= 0.06977463325873284
# differential_evolution step 379: f(x)= 0.06977463325873284
# differential_evolution step 380: f(x)= 0.06977463325873284
# differential_evolution step 381: f(x)= 0.06977463325873284
# differential_evolution step 382: f(x)= 0.06977463325873284
# differential_evolution step 383: f(x)= 0.06977463325873284
# differential_evolution step 384: f(x)= 0.06977463325873284
# differential_evolution step 385: f(x)= 0.06977463325873284
# differential_evolution step 386: f(x)= 0.06971192367542761
# differential_evolution step 387: f(x)= 0.06971192367542761
# differential_evolution step 388: f(x)= 0.06971192367542761
# differential_evolution step 389: f(x)= 0.06971192367542761
# differential_evolution step 390: f(x)= 0.06971192367542761
# differential_evolution step 391: f(x)= 0.06764602552495842
# differential_evolution step 392: f(x)= 0.06764602552495842
# differential_evolution step 393: f(x)= 0.06764602552495842
# differential_evolution step 394: f(x)= 0.06764602552495842
# differential_evolution step 395: f(x)= 0.06764602552495842
# differential_evolution step 396: f(x)= 0.06764602552495842
# differential_evolution step 397: f(x)= 0.06764602552495842
# differential_evolution step 398: f(x)= 0.06764602552495842
# differential_evolution step 399: f(x)= 0.06764602552495842
# differential_evolution step 400: f(x)= 0.06764602552495842
# differential_evolution step 401: f(x)= 0.06764602552495842
# differential_evolution step 402: f(x)= 0.06764602552495842
# differential_evolution step 403: f(x)= 0.06764602552495842
# differential_evolution step 404: f(x)= 0.06764602552495842
# differential_evolution step 405: f(x)= 0.06764602552495842
# differential_evolution step 406: f(x)= 0.06764602552495842
# differential_evolution step 407: f(x)= 0.06764602552495842
# differential_evolution step 408: f(x)= 0.06764602552495842
# differential_evolution step 409: f(x)= 0.06764602552495842
# differential_evolution step 410: f(x)= 0.06764602552495842
# differential_evolution step 411: f(x)= 0.06764602552495842
# differential_evolution step 412: f(x)= 0.06764602552495842
# differential_evolution step 413: f(x)= 0.06764602552495842
# differential_evolution step 414: f(x)= 0.06764602552495842
# differential_evolution step 415: f(x)= 0.06764602552495842
# differential_evolution step 416: f(x)= 0.06764602552495842
# differential_evolution step 417: f(x)= 0.06713307114954492
# differential_evolution step 418: f(x)= 0.06713307114954492
# differential_evolution step 419: f(x)= 0.06713307114954492
# differential_evolution step 420: f(x)= 0.06713307114954492
# differential_evolution step 421: f(x)= 0.06713307114954492
# differential_evolution step 422: f(x)= 0.06713307114954492
# differential_evolution step 423: f(x)= 0.06713307114954492
# differential_evolution step 424: f(x)= 0.06713307114954492
# differential_evolution step 425: f(x)= 0.06713307114954492
# differential_evolution step 426: f(x)= 0.06713307114954492
# differential_evolution step 427: f(x)= 0.06713307114954492
# differential_evolution step 428: f(x)= 0.06713307114954492
# differential_evolution step 429: f(x)= 0.06713307114954492
# differential_evolution step 430: f(x)= 0.06713307114954492
# differential_evolution step 431: f(x)= 0.06713307114954492
# differential_evolution step 432: f(x)= 0.06713307114954492
# differential_evolution step 433: f(x)= 0.06713307114954492
# differential_evolution step 434: f(x)= 0.06713307114954492
# differential_evolution step 435: f(x)= 0.06713307114954492
# differential_evolution step 436: f(x)= 0.06713307114954492
# differential_evolution step 437: f(x)= 0.06713307114954492
# differential_evolution step 438: f(x)= 0.06713307114954492
# differential_evolution step 439: f(x)= 0.06713307114954492
# differential_evolution step 440: f(x)= 0.06713307114954492
# differential_evolution step 441: f(x)= 0.06713307114954492
# differential_evolution step 442: f(x)= 0.06713307114954492
# differential_evolution step 443: f(x)= 0.06713307114954492
# differential_evolution step 444: f(x)= 0.06713307114954492
# differential_evolution step 445: f(x)= 0.06713307114954492
# differential_evolution step 446: f(x)= 0.06713307114954492
# differential_evolution step 447: f(x)= 0.06713307114954492
# differential_evolution step 448: f(x)= 0.06713307114954492
# differential_evolution step 449: f(x)= 0.06713307114954492
# differential_evolution step 450: f(x)= 0.06713307114954492
# differential_evolution step 451: f(x)= 0.06713307114954492
# differential_evolution step 452: f(x)= 0.06713307114954492
# differential_evolution step 453: f(x)= 0.06713307114954492
# differential_evolution step 454: f(x)= 0.06713307114954492
# differential_evolution step 455: f(x)= 0.06713307114954492
# differential_evolution step 456: f(x)= 0.06713307114954492
# differential_evolution step 457: f(x)= 0.06713307114954492
# differential_evolution step 458: f(x)= 0.06713307114954492
# differential_evolution step 459: f(x)= 0.06713307114954492
# differential_evolution step 460: f(x)= 0.06697131909452908
# differential_evolution step 461: f(x)= 0.06697131909452908
# differential_evolution step 462: f(x)= 0.06697131909452908
# differential_evolution step 463: f(x)= 0.06697131909452908
# differential_evolution step 464: f(x)= 0.06697131909452908
# differential_evolution step 465: f(x)= 0.06697131909452908
# differential_evolution step 466: f(x)= 0.06661800318865081
# differential_evolution step 467: f(x)= 0.06661800318865081
# differential_evolution step 468: f(x)= 0.06661800318865081
# differential_evolution step 469: f(x)= 0.06661800318865081
# differential_evolution step 470: f(x)= 0.06661800318865081
# differential_evolution step 471: f(x)= 0.06661800318865081
# differential_evolution step 472: f(x)= 0.06661800318865081
# differential_evolution step 473: f(x)= 0.06661800318865081
# differential_evolution step 474: f(x)= 0.06661800318865081
# differential_evolution step 475: f(x)= 0.06661800318865081
# differential_evolution step 476: f(x)= 0.0658402223004124
# differential_evolution step 477: f(x)= 0.0658402223004124
# differential_evolution step 478: f(x)= 0.0658402223004124
# differential_evolution step 479: f(x)= 0.0658402223004124
# differential_evolution step 480: f(x)= 0.0658402223004124
# differential_evolution step 481: f(x)= 0.0658402223004124
# differential_evolution step 482: f(x)= 0.0658402223004124
# differential_evolution step 483: f(x)= 0.0658402223004124
# differential_evolution step 484: f(x)= 0.0658402223004124
# differential_evolution step 485: f(x)= 0.0658402223004124
# differential_evolution step 486: f(x)= 0.0658402223004124
# differential_evolution step 487: f(x)= 0.0658402223004124
# differential_evolution step 488: f(x)= 0.0658402223004124
# differential_evolution step 489: f(x)= 0.0658402223004124
# differential_evolution step 490: f(x)= 0.0658402223004124
# differential_evolution step 491: f(x)= 0.0658402223004124
# differential_evolution step 492: f(x)= 0.0658402223004124
# differential_evolution step 493: f(x)= 0.06518988149536778
# differential_evolution step 494: f(x)= 0.06518988149536778
# differential_evolution step 495: f(x)= 0.06518988149536778
# differential_evolution step 496: f(x)= 0.06518988149536778
# differential_evolution step 497: f(x)= 0.06518988149536778
# differential_evolution step 498: f(x)= 0.06518988149536778
# differential_evolution step 499: f(x)= 0.06518988149536778
# differential_evolution step 500: f(x)= 0.06518988149536778
# differential_evolution step 501: f(x)= 0.06518988149536778
# differential_evolution step 502: f(x)= 0.06518988149536778
# differential_evolution step 503: f(x)= 0.06518988149536778
# differential_evolution step 504: f(x)= 0.06518988149536778
# differential_evolution step 505: f(x)= 0.06518988149536778
# differential_evolution step 506: f(x)= 0.06518988149536778
# differential_evolution step 507: f(x)= 0.06518988149536778
# differential_evolution step 508: f(x)= 0.06518988149536778
# differential_evolution step 509: f(x)= 0.06518988149536778
# differential_evolution step 510: f(x)= 0.06518988149536778
# differential_evolution step 511: f(x)= 0.06518988149536778
# differential_evolution step 512: f(x)= 0.06518988149536778
# differential_evolution step 513: f(x)= 0.06518988149536778
# differential_evolution step 514: f(x)= 0.06518988149536778
# differential_evolution step 515: f(x)= 0.06518988149536778
# differential_evolution step 516: f(x)= 0.06518988149536778
# differential_evolution step 517: f(x)= 0.06518988149536778
# differential_evolution step 518: f(x)= 0.06518988149536778
# differential_evolution step 519: f(x)= 0.06518254389766664
# differential_evolution step 520: f(x)= 0.06518254389766664
# differential_evolution step 521: f(x)= 0.06518254389766664
# differential_evolution step 522: f(x)= 0.06518254389766664
# differential_evolution step 523: f(x)= 0.06518254389766664
# differential_evolution step 524: f(x)= 0.06518254389766664
# differential_evolution step 525: f(x)= 0.06518254389766664
# differential_evolution step 526: f(x)= 0.06518254389766664
# differential_evolution step 527: f(x)= 0.06518254389766664
# differential_evolution step 528: f(x)= 0.06518254389766664
# differential_evolution step 529: f(x)= 0.06518254389766664
# differential_evolution step 530: f(x)= 0.06518254389766664
# differential_evolution step 531: f(x)= 0.06518254389766664
# differential_evolution step 532: f(x)= 0.06518254389766664
# differential_evolution step 533: f(x)= 0.06518254389766664
# differential_evolution step 534: f(x)= 0.06518254389766664
# differential_evolution step 535: f(x)= 0.06518254389766664
# differential_evolution step 536: f(x)= 0.06518254389766664
# differential_evolution step 537: f(x)= 0.06518254389766664
# differential_evolution step 538: f(x)= 0.06483456311204712
# differential_evolution step 539: f(x)= 0.06483456311204712
# differential_evolution step 540: f(x)= 0.06483456311204712
# differential_evolution step 541: f(x)= 0.06483456311204712
# differential_evolution step 542: f(x)= 0.06483456311204712
# differential_evolution step 543: f(x)= 0.06483456311204712
# differential_evolution step 544: f(x)= 0.06465263535482535
# differential_evolution step 545: f(x)= 0.06465263535482535
# differential_evolution step 546: f(x)= 0.06465263535482535
# differential_evolution step 547: f(x)= 0.06465263535482535
# differential_evolution step 548: f(x)= 0.06465263535482535
# differential_evolution step 549: f(x)= 0.06465263535482535
# differential_evolution step 550: f(x)= 0.06465263535482535
# differential_evolution step 551: f(x)= 0.06465263535482535
# differential_evolution step 552: f(x)= 0.06465263535482535
# differential_evolution step 553: f(x)= 0.06465263535482535
# differential_evolution step 554: f(x)= 0.06465263535482535
# differential_evolution step 555: f(x)= 0.06465263535482535
# differential_evolution step 556: f(x)= 0.06465263535482535
# differential_evolution step 557: f(x)= 0.06465263535482535
# differential_evolution step 558: f(x)= 0.06465263535482535
# differential_evolution step 559: f(x)= 0.06465263535482535
# differential_evolution step 560: f(x)= 0.06465263535482535
# differential_evolution step 561: f(x)= 0.06465263535482535
# differential_evolution step 562: f(x)= 0.06465263535482535
# differential_evolution step 563: f(x)= 0.06465263535482535
# differential_evolution step 564: f(x)= 0.06465263535482535
# differential_evolution step 565: f(x)= 0.06465263535482535
# differential_evolution step 566: f(x)= 0.06465263535482535
# differential_evolution step 567: f(x)= 0.06465263535482535
# differential_evolution step 568: f(x)= 0.06465263535482535
# differential_evolution step 569: f(x)= 0.06465263535482535
# differential_evolution step 570: f(x)= 0.06465263535482535
# differential_evolution step 571: f(x)= 0.06465263535482535
# differential_evolution step 572: f(x)= 0.06465263535482535
# differential_evolution step 573: f(x)= 0.06465263535482535
# differential_evolution step 574: f(x)= 0.06452741762371379
# differential_evolution step 575: f(x)= 0.06452741762371379
# differential_evolution step 576: f(x)= 0.06452741762371379
# differential_evolution step 577: f(x)= 0.06452741762371379
# differential_evolution step 578: f(x)= 0.06452741762371379
# differential_evolution step 579: f(x)= 0.06452741762371379
# differential_evolution step 580: f(x)= 0.06452741762371379
# differential_evolution step 581: f(x)= 0.06452741762371379
# differential_evolution step 582: f(x)= 0.06452741762371379
# differential_evolution step 583: f(x)= 0.06452741762371379
# differential_evolution step 584: f(x)= 0.06452741762371379
# differential_evolution step 585: f(x)= 0.06452741762371379
# differential_evolution step 586: f(x)= 0.06452741762371379
# differential_evolution step 587: f(x)= 0.06452741762371379
# differential_evolution step 588: f(x)= 0.06452741762371379
# differential_evolution step 589: f(x)= 0.06452741762371379
# differential_evolution step 590: f(x)= 0.06452741762371379
# differential_evolution step 591: f(x)= 0.06452741762371379
# differential_evolution step 592: f(x)= 0.06452741762371379
# differential_evolution step 593: f(x)= 0.06452741762371379
# differential_evolution step 594: f(x)= 0.06452741762371379
# differential_evolution step 595: f(x)= 0.06452741762371379
# differential_evolution step 596: f(x)= 0.06431286231793293
# differential_evolution step 597: f(x)= 0.06431286231793293
# differential_evolution step 598: f(x)= 0.06431286231793293
# differential_evolution step 599: f(x)= 0.06431286231793293
# differential_evolution step 600: f(x)= 0.06431286231793293
# differential_evolution step 601: f(x)= 0.06431286231793293
# differential_evolution step 602: f(x)= 0.06431286231793293
# differential_evolution step 603: f(x)= 0.06431286231793293
# differential_evolution step 604: f(x)= 0.06431286231793293
# differential_evolution step 605: f(x)= 0.06431286231793293
# differential_evolution step 606: f(x)= 0.06431286231793293
# differential_evolution step 607: f(x)= 0.06431286231793293
# differential_evolution step 608: f(x)= 0.06431286231793293
# differential_evolution step 609: f(x)= 0.06431286231793293
# differential_evolution step 610: f(x)= 0.06431286231793293
# differential_evolution step 611: f(x)= 0.06431286231793293
# differential_evolution step 612: f(x)= 0.06431286231793293
# differential_evolution step 613: f(x)= 0.06431286231793293
# differential_evolution step 614: f(x)= 0.06431286231793293
# differential_evolution step 615: f(x)= 0.06407308245869489
# differential_evolution step 616: f(x)= 0.06407308245869489
# differential_evolution step 617: f(x)= 0.06407308245869489
# differential_evolution step 618: f(x)= 0.06407308245869489
# differential_evolution step 619: f(x)= 0.06407308245869489
# differential_evolution step 620: f(x)= 0.06407308245869489
# differential_evolution step 621: f(x)= 0.06407308245869489
# differential_evolution step 622: f(x)= 0.06407308245869489
# differential_evolution step 623: f(x)= 0.06407308245869489
# differential_evolution step 624: f(x)= 0.06366505159773789
# differential_evolution step 625: f(x)= 0.06366505159773789
# differential_evolution step 626: f(x)= 0.06366505159773789
# differential_evolution step 627: f(x)= 0.06366505159773789
# differential_evolution step 628: f(x)= 0.06366505159773789
# differential_evolution step 629: f(x)= 0.06366505159773789
# differential_evolution step 630: f(x)= 0.06366505159773789
# differential_evolution step 631: f(x)= 0.06366505159773789
# differential_evolution step 632: f(x)= 0.06366505159773789
# differential_evolution step 633: f(x)= 0.06366505159773789
# differential_evolution step 634: f(x)= 0.06366505159773789
# differential_evolution step 635: f(x)= 0.06366505159773789
# differential_evolution step 636: f(x)= 0.06366505159773789
# differential_evolution step 637: f(x)= 0.06366505159773789
# differential_evolution step 638: f(x)= 0.06366505159773789
# differential_evolution step 639: f(x)= 0.06366505159773789
# differential_evolution step 640: f(x)= 0.06366505159773789
# differential_evolution step 641: f(x)= 0.06366505159773789
# differential_evolution step 642: f(x)= 0.06366505159773789
# differential_evolution step 643: f(x)= 0.06366505159773789
# differential_evolution step 644: f(x)= 0.06339524632504008
# differential_evolution step 645: f(x)= 0.06339524632504008
# differential_evolution step 646: f(x)= 0.06339524632504008
# differential_evolution step 647: f(x)= 0.06339524632504008
# differential_evolution step 648: f(x)= 0.06339524632504008
# differential_evolution step 649: f(x)= 0.06339524632504008
# differential_evolution step 650: f(x)= 0.06339524632504008
# differential_evolution step 651: f(x)= 0.06339524632504008
# differential_evolution step 652: f(x)= 0.06339524632504008
# differential_evolution step 653: f(x)= 0.06339524632504008
# differential_evolution step 654: f(x)= 0.06339524632504008
# differential_evolution step 655: f(x)= 0.06339524632504008
# differential_evolution step 656: f(x)= 0.06339524632504008
# differential_evolution step 657: f(x)= 0.06339524632504008
# differential_evolution step 658: f(x)= 0.06339524632504008
# differential_evolution step 659: f(x)= 0.06339524632504008
# differential_evolution step 660: f(x)= 0.06339524632504008
# differential_evolution step 661: f(x)= 0.06339524632504008
# differential_evolution step 662: f(x)= 0.06339524632504008
# differential_evolution step 663: f(x)= 0.06339524632504008
# differential_evolution step 664: f(x)= 0.06339524632504008
# differential_evolution step 665: f(x)= 0.06339524632504008
# differential_evolution step 666: f(x)= 0.06339524632504008
# differential_evolution step 667: f(x)= 0.06339524632504008
# differential_evolution step 668: f(x)= 0.06339524632504008
# differential_evolution step 669: f(x)= 0.06339524632504008
# differential_evolution step 670: f(x)= 0.06339524632504008
# differential_evolution step 671: f(x)= 0.06339524632504008
# differential_evolution step 672: f(x)= 0.06339524632504008
# differential_evolution step 673: f(x)= 0.06339524632504008
# differential_evolution step 674: f(x)= 0.06339524632504008
# differential_evolution step 675: f(x)= 0.06339524632504008
# differential_evolution step 676: f(x)= 0.06339524632504008
# differential_evolution step 677: f(x)= 0.06339524632504008
# differential_evolution step 678: f(x)= 0.06339524632504008
# differential_evolution step 679: f(x)= 0.06339524632504008
# differential_evolution step 680: f(x)= 0.06339524632504008
# differential_evolution step 681: f(x)= 0.06339524632504008
# differential_evolution step 682: f(x)= 0.0633768276361587
# differential_evolution step 683: f(x)= 0.0633768276361587
# differential_evolution step 684: f(x)= 0.0633768276361587
# differential_evolution step 685: f(x)= 0.0633768276361587
# differential_evolution step 686: f(x)= 0.0633768276361587
# differential_evolution step 687: f(x)= 0.0633768276361587
# differential_evolution step 688: f(x)= 0.0633768276361587
# differential_evolution step 689: f(x)= 0.0633768276361587
# differential_evolution step 690: f(x)= 0.0633768276361587
# differential_evolution step 691: f(x)= 0.0633768276361587
# differential_evolution step 692: f(x)= 0.0633768276361587
# differential_evolution step 693: f(x)= 0.06313316208545096
# differential_evolution step 694: f(x)= 0.06313316208545096
# differential_evolution step 695: f(x)= 0.06313316208545096
# differential_evolution step 696: f(x)= 0.06313316208545096
# differential_evolution step 697: f(x)= 0.06313316208545096
# differential_evolution step 698: f(x)= 0.06313316208545096
# differential_evolution step 699: f(x)= 0.06313316208545096
# differential_evolution step 700: f(x)= 0.06313316208545096
# differential_evolution step 701: f(x)= 0.06313316208545096
# differential_evolution step 702: f(x)= 0.06313316208545096
# differential_evolution step 703: f(x)= 0.06313316208545096
# differential_evolution step 704: f(x)= 0.06313316208545096
# differential_evolution step 705: f(x)= 0.06313316208545096
# differential_evolution step 706: f(x)= 0.06313316208545096
# differential_evolution step 707: f(x)= 0.06313316208545096
# differential_evolution step 708: f(x)= 0.06313316208545096
# differential_evolution step 709: f(x)= 0.06313316208545096
# differential_evolution step 710: f(x)= 0.06313316208545096
# differential_evolution step 711: f(x)= 0.06313316208545096
# differential_evolution step 712: f(x)= 0.06313316208545096
# differential_evolution step 713: f(x)= 0.06313316208545096
# differential_evolution step 714: f(x)= 0.06313316208545096
# differential_evolution step 715: f(x)= 0.06313316208545096
# differential_evolution step 716: f(x)= 0.06313316208545096
# differential_evolution step 717: f(x)= 0.06313316208545096
# differential_evolution step 718: f(x)= 0.06313316208545096
# differential_evolution step 719: f(x)= 0.06313316208545096
# differential_evolution step 720: f(x)= 0.06313316208545096
# differential_evolution step 721: f(x)= 0.06313316208545096
# differential_evolution step 722: f(x)= 0.06313316208545096
# differential_evolution step 723: f(x)= 0.06313316208545096
# differential_evolution step 724: f(x)= 0.06313316208545096
# differential_evolution step 725: f(x)= 0.06313316208545096
# differential_evolution step 726: f(x)= 0.06313316208545096
# differential_evolution step 727: f(x)= 0.06313316208545096
# differential_evolution step 728: f(x)= 0.06313316208545096
# differential_evolution step 729: f(x)= 0.06313316208545096
# differential_evolution step 730: f(x)= 0.06313316208545096
# differential_evolution step 731: f(x)= 0.06313316208545096
# differential_evolution step 732: f(x)= 0.06313316208545096
# differential_evolution step 733: f(x)= 0.06313316208545096
# differential_evolution step 734: f(x)= 0.06313316208545096
# differential_evolution step 735: f(x)= 0.06313316208545096
# differential_evolution step 736: f(x)= 0.06313316208545096
# differential_evolution step 737: f(x)= 0.06313316208545096
# differential_evolution step 738: f(x)= 0.06313316208545096
# differential_evolution step 739: f(x)= 0.06313316208545096
# differential_evolution step 740: f(x)= 0.06313316208545096
# differential_evolution step 741: f(x)= 0.06313316208545096
# differential_evolution step 742: f(x)= 0.06313316208545096
# differential_evolution step 743: f(x)= 0.06313316208545096
# differential_evolution step 744: f(x)= 0.06313316208545096
# differential_evolution step 745: f(x)= 0.06313316208545096
# differential_evolution step 746: f(x)= 0.06313316208545096
# differential_evolution step 747: f(x)= 0.06313316208545096
# differential_evolution step 748: f(x)= 0.06313316208545096
# differential_evolution step 749: f(x)= 0.06313316208545096
# differential_evolution step 750: f(x)= 0.06313316208545096
# differential_evolution step 751: f(x)= 0.06313316208545096
# differential_evolution step 752: f(x)= 0.06313316208545096
# differential_evolution step 753: f(x)= 0.06313316208545096
# differential_evolution step 754: f(x)= 0.06313316208545096
# differential_evolution step 755: f(x)= 0.06313316208545096
# differential_evolution step 756: f(x)= 0.06313316208545096
# differential_evolution step 757: f(x)= 0.06313316208545096
# differential_evolution step 758: f(x)= 0.06313316208545096
# differential_evolution step 759: f(x)= 0.06313316208545096
# differential_evolution step 760: f(x)= 0.06313316208545096
# differential_evolution step 761: f(x)= 0.06313316208545096
# differential_evolution step 762: f(x)= 0.06313316208545096
# differential_evolution step 763: f(x)= 0.06313316208545096
# differential_evolution step 764: f(x)= 0.06313316208545096
# differential_evolution step 765: f(x)= 0.06313316208545096
# differential_evolution step 766: f(x)= 0.06313316208545096
# differential_evolution step 767: f(x)= 0.06313316208545096
# differential_evolution step 768: f(x)= 0.06313316208545096
# differential_evolution step 769: f(x)= 0.06313316208545096
# differential_evolution step 770: f(x)= 0.06313316208545096
# differential_evolution step 771: f(x)= 0.06313316208545096
# differential_evolution step 772: f(x)= 0.06313316208545096
# differential_evolution step 773: f(x)= 0.06313316208545096
# differential_evolution step 774: f(x)= 0.06274506434947356
# differential_evolution step 775: f(x)= 0.06274506434947356
# differential_evolution step 776: f(x)= 0.06274506434947356

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))
real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')

# %%
# Bounds:
bounds = bounds_HA
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 240: f(x)= 0.02489223747613232
# differential_evolution step 241: f(x)= 0.023641675186895916
# differential_evolution step 242: f(x)= 0.023641675186895916
# differential_evolution step 243: f(x)= 0.023641675186895916
# differential_evolution step 244: f(x)= 0.023641675186895916
# differential_evolution step 245: f(x)= 0.023641675186895916
# differential_evolution step 246: f(x)= 0.023641675186895916
# differential_evolution step 247: f(x)= 0.023641675186895916
# differential_evolution step 248: f(x)= 0.023641675186895916
# differential_evolution step 249: f(x)= 0.023641675186895916
# differential_evolution step 250: f(x)= 0.023641675186895916
# differential_evolution step 251: f(x)= 0.023641675186895916
# differential_evolution step 252: f(x)= 0.023641675186895916
# differential_evolution step 253: f(x)= 0.023641675186895916
# differential_evolution step 254: f(x)= 0.023641675186895916
# differential_evolution step 255: f(x)= 0.023641675186895916
# differential_evolution step 256: f(x)= 0.023641675186895916
# differential_evolution step 257: f(x)= 0.023641675186895916
# differential_evolution step 258: f(x)= 0.023641675186895916
# differential_evolution step 259: f(x)= 0.023641675186895916
# differential_evolution step 260: f(x)= 0.023641675186895916
# differential_evolution step 261: f(x)= 0.023641675186895916
# differential_evolution step 262: f(x)= 0.023641675186895916
# differential_evolution step 263: f(x)= 0.023641675186895916
# differential_evolution step 264: f(x)= 0.023641675186895916
# differential_evolution step 265: f(x)= 0.023641675186895916
# differential_evolution step 266: f(x)= 0.023641675186895916
# differential_evolution step 267: f(x)= 0.023641675186895916
# differential_evolution step 268: f(x)= 0.023641675186895916
# differential_evolution step 269: f(x)= 0.023641675186895916
# differential_evolution step 270: f(x)= 0.023641675186895916
# differential_evolution step 271: f(x)= 0.023641675186895916
# differential_evolution step 272: f(x)= 0.023641675186895916
# differential_evolution step 273: f(x)= 0.023641675186895916
# differential_evolution step 274: f(x)= 0.023641675186895916
# differential_evolution step 275: f(x)= 0.023641675186895916
# differential_evolution step 276: f(x)= 0.023641675186895916
# differential_evolution step 277: f(x)= 0.023641675186895916
# differential_evolution step 278: f(x)= 0.023641675186895916
# differential_evolution step 279: f(x)= 0.0234661156858518
# differential_evolution step 280: f(x)= 0.0234661156858518
# differential_evolution step 281: f(x)= 0.022721432926795914
# differential_evolution step 282: f(x)= 0.022721432926795914
# differential_evolution step 283: f(x)= 0.022721432926795914
# differential_evolution step 284: f(x)= 0.022721432926795914
# differential_evolution step 285: f(x)= 0.022721432926795914
# differential_evolution step 286: f(x)= 0.022721432926795914
# differential_evolution step 287: f(x)= 0.022721432926795914
# differential_evolution step 288: f(x)= 0.022721432926795914
# differential_evolution step 289: f(x)= 0.022721432926795914
# differential_evolution step 290: f(x)= 0.02221482021039645
# differential_evolution step 291: f(x)= 0.02221482021039645
# differential_evolution step 292: f(x)= 0.02221482021039645
# differential_evolution step 293: f(x)= 0.02221482021039645
# differential_evolution step 294: f(x)= 0.02221482021039645
# differential_evolution step 295: f(x)= 0.02221482021039645
# differential_evolution step 296: f(x)= 0.02221482021039645
# differential_evolution step 297: f(x)= 0.02221482021039645
# differential_evolution step 298: f(x)= 0.02221482021039645
# differential_evolution step 299: f(x)= 0.02221482021039645
# differential_evolution step 300: f(x)= 0.02221482021039645
# differential_evolution step 301: f(x)= 0.02090441781506578
# differential_evolution step 302: f(x)= 0.02090441781506578
# differential_evolution step 303: f(x)= 0.02090441781506578
# differential_evolution step 304: f(x)= 0.02090441781506578
# differential_evolution step 305: f(x)= 0.02090441781506578
# differential_evolution step 306: f(x)= 0.02090441781506578
# differential_evolution step 307: f(x)= 0.02090441781506578
# differential_evolution step 308: f(x)= 0.02090441781506578
# differential_evolution step 309: f(x)= 0.02090441781506578
# differential_evolution step 310: f(x)= 0.02090441781506578
# differential_evolution step 311: f(x)= 0.02090441781506578
# differential_evolution step 312: f(x)= 0.02090441781506578
# differential_evolution step 313: f(x)= 0.02090441781506578
# differential_evolution step 314: f(x)= 0.02090441781506578
# differential_evolution step 315: f(x)= 0.02090441781506578
# differential_evolution step 316: f(x)= 0.02090441781506578
# differential_evolution step 317: f(x)= 0.02090441781506578
# differential_evolution step 318: f(x)= 0.02090441781506578
# differential_evolution step 319: f(x)= 0.02090441781506578
# differential_evolution step 320: f(x)= 0.02090441781506578
# differential_evolution step 321: f(x)= 0.02090441781506578
# differential_evolution step 322: f(x)= 0.02090441781506578
# differential_evolution step 323: f(x)= 0.02090441781506578
# differential_evolution step 324: f(x)= 0.02090441781506578
# differential_evolution step 325: f(x)= 0.02090441781506578
# differential_evolution step 326: f(x)= 0.02090441781506578
# differential_evolution step 327: f(x)= 0.02090441781506578
# differential_evolution step 328: f(x)= 0.02090441781506578
# differential_evolution step 329: f(x)= 0.02090441781506578
# differential_evolution step 330: f(x)= 0.02090441781506578
# differential_evolution step 331: f(x)= 0.02090441781506578
# differential_evolution step 332: f(x)= 0.02090441781506578
# differential_evolution step 333: f(x)= 0.02090441781506578
# differential_evolution step 334: f(x)= 0.02090441781506578
# differential_evolution step 335: f(x)= 0.02090441781506578
# differential_evolution step 336: f(x)= 0.02090441781506578
# differential_evolution step 337: f(x)= 0.02090441781506578
# differential_evolution step 338: f(x)= 0.02090441781506578
# differential_evolution step 339: f(x)= 0.02090441781506578
# differential_evolution step 340: f(x)= 0.02090441781506578
# differential_evolution step 341: f(x)= 0.02090441781506578
# differential_evolution step 342: f(x)= 0.020770085092022834
# differential_evolution step 343: f(x)= 0.020770085092022834
# differential_evolution step 344: f(x)= 0.020770085092022834
# differential_evolution step 345: f(x)= 0.020770085092022834
# differential_evolution step 346: f(x)= 0.020592770925065708
# differential_evolution step 347: f(x)= 0.020592770925065708
# differential_evolution step 348: f(x)= 0.020592770925065708
# differential_evolution step 349: f(x)= 0.020378880079074933
# differential_evolution step 350: f(x)= 0.020378880079074933
# differential_evolution step 351: f(x)= 0.020378880079074933
# differential_evolution step 352: f(x)= 0.020378880079074933
# differential_evolution step 353: f(x)= 0.019692806548307913
# differential_evolution step 354: f(x)= 0.019692806548307913
# differential_evolution step 355: f(x)= 0.019692806548307913
# differential_evolution step 356: f(x)= 0.019692806548307913
# differential_evolution step 357: f(x)= 0.01955563951429249
# differential_evolution step 358: f(x)= 0.01955563951429249
# differential_evolution step 359: f(x)= 0.01955563951429249
# differential_evolution step 360: f(x)= 0.01955563951429249
# differential_evolution step 361: f(x)= 0.01955563951429249
# differential_evolution step 362: f(x)= 0.01955563951429249
# differential_evolution step 363: f(x)= 0.01955563951429249
# differential_evolution step 364: f(x)= 0.01955563951429249
# differential_evolution step 365: f(x)= 0.01955563951429249
# differential_evolution step 366: f(x)= 0.019114158319364517
# differential_evolution step 367: f(x)= 0.019114158319364517
# differential_evolution step 368: f(x)= 0.019114158319364517
# differential_evolution step 369: f(x)= 0.019114158319364517
# differential_evolution step 370: f(x)= 0.019071056992734037
# differential_evolution step 371: f(x)= 0.019071056992734037
# differential_evolution step 372: f(x)= 0.019071056992734037
# differential_evolution step 373: f(x)= 0.019071056992734037
# differential_evolution step 374: f(x)= 0.019071056992734037
# differential_evolution step 375: f(x)= 0.019071056992734037
# differential_evolution step 376: f(x)= 0.019071056992734037
# differential_evolution step 377: f(x)= 0.019071056992734037
# differential_evolution step 378: f(x)= 0.019071056992734037
# differential_evolution step 379: f(x)= 0.019071056992734037
# differential_evolution step 380: f(x)= 0.019071056992734037
# differential_evolution step 381: f(x)= 0.019071056992734037
# differential_evolution step 382: f(x)= 0.019071056992734037
# differential_evolution step 383: f(x)= 0.019071056992734037
# differential_evolution step 384: f(x)= 0.019071056992734037
# differential_evolution step 385: f(x)= 0.019071056992734037
# differential_evolution step 386: f(x)= 0.019071056992734037
# differential_evolution step 387: f(x)= 0.019071056992734037
# differential_evolution step 388: f(x)= 0.019071056992734037
# differential_evolution step 389: f(x)= 0.019071056992734037
# differential_evolution step 390: f(x)= 0.019071056992734037
# differential_evolution step 391: f(x)= 0.019071056992734037
# differential_evolution step 392: f(x)= 0.019071056992734037
# differential_evolution step 393: f(x)= 0.019071056992734037
# differential_evolution step 394: f(x)= 0.019071056992734037
# differential_evolution step 395: f(x)= 0.019071056992734037
# differential_evolution step 396: f(x)= 0.019071056992734037
# differential_evolution step 397: f(x)= 0.019071056992734037
# differential_evolution step 398: f(x)= 0.019071056992734037
# differential_evolution step 399: f(x)= 0.019071056992734037
# differential_evolution step 400: f(x)= 0.019071056992734037
# differential_evolution step 401: f(x)= 0.019071056992734037
# differential_evolution step 402: f(x)= 0.019071056992734037
# differential_evolution step 403: f(x)= 0.019071056992734037
# differential_evolution step 404: f(x)= 0.019071056992734037
# differential_evolution step 405: f(x)= 0.019071056992734037
# differential_evolution step 406: f(x)= 0.019071056992734037
# differential_evolution step 407: f(x)= 0.019071056992734037
# differential_evolution step 408: f(x)= 0.019071056992734037
# differential_evolution step 409: f(x)= 0.019071056992734037
# differential_evolution step 410: f(x)= 0.019071056992734037
# differential_evolution step 411: f(x)= 0.019071056992734037
# differential_evolution step 412: f(x)= 0.019071056992734037
# differential_evolution step 413: f(x)= 0.019071056992734037
# differential_evolution step 414: f(x)= 0.019071056992734037
# differential_evolution step 415: f(x)= 0.019071056992734037
# differential_evolution step 416: f(x)= 0.019071056992734037
# differential_evolution step 417: f(x)= 0.019071056992734037
# differential_evolution step 418: f(x)= 0.019071056992734037
# differential_evolution step 419: f(x)= 0.019071056992734037
# differential_evolution step 420: f(x)= 0.019071056992734037
# differential_evolution step 421: f(x)= 0.019071056992734037
# differential_evolution step 422: f(x)= 0.019071056992734037
# differential_evolution step 423: f(x)= 0.019071056992734037
# differential_evolution step 424: f(x)= 0.019071056992734037
# differential_evolution step 425: f(x)= 0.018916846820721644
# differential_evolution step 426: f(x)= 0.018916846820721644
# differential_evolution step 427: f(x)= 0.018916846820721644
# differential_evolution step 428: f(x)= 0.018916846820721644
# differential_evolution step 429: f(x)= 0.018916846820721644
# differential_evolution step 430: f(x)= 0.018916846820721644
# differential_evolution step 431: f(x)= 0.01891251025517911
# differential_evolution step 432: f(x)= 0.01891251025517911
# differential_evolution step 433: f(x)= 0.01891251025517911
# differential_evolution step 434: f(x)= 0.01891251025517911
# differential_evolution step 435: f(x)= 0.01891251025517911
# differential_evolution step 436: f(x)= 0.01891251025517911
# differential_evolution step 437: f(x)= 0.01891251025517911
# differential_evolution step 438: f(x)= 0.01891251025517911
# differential_evolution step 439: f(x)= 0.01891251025517911
# differential_evolution step 440: f(x)= 0.01891251025517911
# differential_evolution step 441: f(x)= 0.01891251025517911
# differential_evolution step 442: f(x)= 0.01891251025517911
# differential_evolution step 443: f(x)= 0.01891251025517911
# differential_evolution step 444: f(x)= 0.01891251025517911
# differential_evolution step 445: f(x)= 0.01891251025517911
# differential_evolution step 446: f(x)= 0.01891251025517911
# differential_evolution step 447: f(x)= 0.01891251025517911
# differential_evolution step 448: f(x)= 0.01891251025517911
# differential_evolution step 449: f(x)= 0.01891251025517911
# differential_evolution step 450: f(x)= 0.01891251025517911
# differential_evolution step 451: f(x)= 0.01891251025517911
# differential_evolution step 452: f(x)= 0.01891251025517911
# differential_evolution step 453: f(x)= 0.01891251025517911
# differential_evolution step 454: f(x)= 0.01891251025517911
# differential_evolution step 455: f(x)= 0.01891251025517911
# differential_evolution step 456: f(x)= 0.01891251025517911
# differential_evolution step 457: f(x)= 0.01891251025517911
# differential_evolution step 458: f(x)= 0.018453737874611475
# differential_evolution step 459: f(x)= 0.018453737874611475
# differential_evolution step 460: f(x)= 0.018453737874611475
# differential_evolution step 461: f(x)= 0.018453737874611475
# differential_evolution step 462: f(x)= 0.018453737874611475
# differential_evolution step 463: f(x)= 0.018453737874611475
# differential_evolution step 464: f(x)= 0.018453737874611475
# differential_evolution step 465: f(x)= 0.018453737874611475
# differential_evolution step 466: f(x)= 0.018453737874611475
# differential_evolution step 467: f(x)= 0.018453737874611475
# differential_evolution step 468: f(x)= 0.018130212278750814
# differential_evolution step 469: f(x)= 0.018130212278750814
# differential_evolution step 470: f(x)= 0.018130212278750814
# differential_evolution step 471: f(x)= 0.018130212278750814
# differential_evolution step 472: f(x)= 0.018130212278750814
# differential_evolution step 473: f(x)= 0.018130212278750814
# differential_evolution step 474: f(x)= 0.018130212278750814
# differential_evolution step 475: f(x)= 0.018130212278750814
# differential_evolution step 476: f(x)= 0.018130212278750814
# differential_evolution step 477: f(x)= 0.018130212278750814
# differential_evolution step 478: f(x)= 0.018130212278750814
# differential_evolution step 479: f(x)= 0.018130212278750814
# differential_evolution step 480: f(x)= 0.018130212278750814
# differential_evolution step 481: f(x)= 0.018130212278750814
# differential_evolution step 482: f(x)= 0.018130212278750814
# differential_evolution step 483: f(x)= 0.018130212278750814
# differential_evolution step 484: f(x)= 0.018130212278750814
# differential_evolution step 485: f(x)= 0.018130212278750814
# differential_evolution step 486: f(x)= 0.018130212278750814
# differential_evolution step 487: f(x)= 0.018130212278750814
# differential_evolution step 488: f(x)= 0.018130212278750814
# differential_evolution step 489: f(x)= 0.018130212278750814
# differential_evolution step 490: f(x)= 0.018130212278750814
# differential_evolution step 491: f(x)= 0.018130212278750814
# differential_evolution step 492: f(x)= 0.018130212278750814
# differential_evolution step 493: f(x)= 0.018130212278750814
# differential_evolution step 494: f(x)= 0.018130212278750814
# differential_evolution step 495: f(x)= 0.018130212278750814
# differential_evolution step 496: f(x)= 0.018130212278750814
# differential_evolution step 497: f(x)= 0.018130212278750814
# differential_evolution step 498: f(x)= 0.018130212278750814
# differential_evolution step 499: f(x)= 0.018130212278750814
# differential_evolution step 500: f(x)= 0.018130212278750814
# differential_evolution step 501: f(x)= 0.018130212278750814
# differential_evolution step 502: f(x)= 0.018130212278750814
# differential_evolution step 503: f(x)= 0.018130212278750814
# differential_evolution step 504: f(x)= 0.018130212278750814
# differential_evolution step 505: f(x)= 0.018130212278750814
# differential_evolution step 506: f(x)= 0.018130212278750814
# differential_evolution step 507: f(x)= 0.018130212278750814
# differential_evolution step 508: f(x)= 0.018130212278750814
# differential_evolution step 509: f(x)= 0.018130212278750814
# differential_evolution step 510: f(x)= 0.018130212278750814
# differential_evolution step 511: f(x)= 0.018130212278750814
# differential_evolution step 512: f(x)= 0.018130212278750814
# differential_evolution step 513: f(x)= 0.018130212278750814
# differential_evolution step 514: f(x)= 0.018130212278750814
# differential_evolution step 515: f(x)= 0.018130212278750814
# differential_evolution step 516: f(x)= 0.018130212278750814
# differential_evolution step 517: f(x)= 0.018130212278750814
# differential_evolution step 518: f(x)= 0.018130212278750814
# differential_evolution step 519: f(x)= 0.018130212278750814
# differential_evolution step 520: f(x)= 0.018130212278750814
# differential_evolution step 521: f(x)= 0.018130212278750814
# differential_evolution step 522: f(x)= 0.018130212278750814
# differential_evolution step 523: f(x)= 0.018130212278750814
# differential_evolution step 524: f(x)= 0.018130212278750814
# differential_evolution step 525: f(x)= 0.018130212278750814
# differential_evolution step 526: f(x)= 0.018130212278750814
# differential_evolution step 527: f(x)= 0.018130212278750814
# differential_evolution step 528: f(x)= 0.018130212278750814
# differential_evolution step 529: f(x)= 0.018130212278750814
# differential_evolution step 530: f(x)= 0.018130212278750814
# differential_evolution step 531: f(x)= 0.018130212278750814
# differential_evolution step 532: f(x)= 0.018130212278750814
# differential_evolution step 533: f(x)= 0.018130212278750814
# differential_evolution step 534: f(x)= 0.018130212278750814
# differential_evolution step 535: f(x)= 0.018130212278750814
# differential_evolution step 536: f(x)= 0.018130212278750814
# differential_evolution step 537: f(x)= 0.018130212278750814
# differential_evolution step 538: f(x)= 0.018130212278750814
# differential_evolution step 539: f(x)= 0.018130212278750814
# differential_evolution step 540: f(x)= 0.018130212278750814
# differential_evolution step 541: f(x)= 0.018130212278750814
# differential_evolution step 542: f(x)= 0.018130212278750814
# differential_evolution step 543: f(x)= 0.018130212278750814
# differential_evolution step 544: f(x)= 0.018130212278750814
# differential_evolution step 545: f(x)= 0.018130212278750814
# differential_evolution step 546: f(x)= 0.018130212278750814
# differential_evolution step 547: f(x)= 0.018130212278750814
# differential_evolution step 548: f(x)= 0.018130212278750814
# differential_evolution step 549: f(x)= 0.018130212278750814
# differential_evolution step 550: f(x)= 0.018130212278750814
# differential_evolution step 551: f(x)= 0.018130212278750814
# differential_evolution step 552: f(x)= 0.018130212278750814
# differential_evolution step 553: f(x)= 0.018130212278750814
# differential_evolution step 554: f(x)= 0.018130212278750814
# differential_evolution step 555: f(x)= 0.018130212278750814
# differential_evolution step 556: f(x)= 0.018130212278750814
# differential_evolution step 557: f(x)= 0.018130212278750814
# differential_evolution step 558: f(x)= 0.018130212278750814
# differential_evolution step 559: f(x)= 0.018130212278750814
# differential_evolution step 560: f(x)= 0.01812785715940093
# differential_evolution step 561: f(x)= 0.01812785715940093
# differential_evolution step 562: f(x)= 0.01812785715940093
# differential_evolution step 563: f(x)= 0.01812785715940093
# differential_evolution step 564: f(x)= 0.01812785715940093
# differential_evolution step 565: f(x)= 0.01812785715940093
# differential_evolution step 566: f(x)= 0.01812785715940093
# differential_evolution step 567: f(x)= 0.01812785715940093
# differential_evolution step 568: f(x)= 0.01812785715940093
# differential_evolution step 569: f(x)= 0.01812785715940093
# differential_evolution step 570: f(x)= 0.01812785715940093
# differential_evolution step 571: f(x)= 0.01812785715940093
# differential_evolution step 572: f(x)= 0.01812785715940093
# differential_evolution step 573: f(x)= 0.01812785715940093
# differential_evolution step 574: f(x)= 0.01812785715940093
# differential_evolution step 575: f(x)= 0.01812785715940093
# differential_evolution step 576: f(x)= 0.01812785715940093
# differential_evolution step 577: f(x)= 0.01812785715940093
# differential_evolution step 578: f(x)= 0.017916387552082684
# differential_evolution step 579: f(x)= 0.017916387552082684
# differential_evolution step 580: f(x)= 0.017916387552082684
# differential_evolution step 581: f(x)= 0.017916387552082684
# differential_evolution step 582: f(x)= 0.017916387552082684
# differential_evolution step 583: f(x)= 0.017916387552082684
# differential_evolution step 584: f(x)= 0.017916387552082684
# differential_evolution step 585: f(x)= 0.017916387552082684
# differential_evolution step 586: f(x)= 0.017916387552082684
# differential_evolution step 587: f(x)= 0.017916387552082684
# differential_evolution step 588: f(x)= 0.017730487845482958
# differential_evolution step 589: f(x)= 0.017730487845482958
# differential_evolution step 590: f(x)= 0.017730487845482958
# differential_evolution step 591: f(x)= 0.017730487845482958
# differential_evolution step 592: f(x)= 0.017730487845482958
# differential_evolution step 593: f(x)= 0.017730487845482958
# differential_evolution step 594: f(x)= 0.017730487845482958
# differential_evolution step 595: f(x)= 0.017730487845482958
# differential_evolution step 596: f(x)= 0.017730487845482958
# differential_evolution step 597: f(x)= 0.017730487845482958
# differential_evolution step 598: f(x)= 0.017730487845482958
# differential_evolution step 599: f(x)= 0.017730487845482958
# differential_evolution step 600: f(x)= 0.017730487845482958
# differential_evolution step 601: f(x)= 0.017730487845482958
# differential_evolution step 602: f(x)= 0.017590320429324603
# differential_evolution step 603: f(x)= 0.017590320429324603
# differential_evolution step 604: f(x)= 0.017590320429324603
# differential_evolution step 605: f(x)= 0.017590320429324603
# differential_evolution step 606: f(x)= 0.017590320429324603
# differential_evolution step 607: f(x)= 0.017590320429324603
# differential_evolution step 608: f(x)= 0.017590320429324603
# differential_evolution step 609: f(x)= 0.017590320429324603
# differential_evolution step 610: f(x)= 0.017590320429324603
# differential_evolution step 611: f(x)= 0.017590320429324603
# differential_evolution step 612: f(x)= 0.017590320429324603
# differential_evolution step 613: f(x)= 0.017590320429324603
# differential_evolution step 614: f(x)= 0.017590320429324603
# differential_evolution step 615: f(x)= 0.017590320429324603
# differential_evolution step 616: f(x)= 0.017590320429324603
# differential_evolution step 617: f(x)= 0.017590320429324603
# differential_evolution step 618: f(x)= 0.017590320429324603
# differential_evolution step 619: f(x)= 0.017590320429324603
# differential_evolution step 620: f(x)= 0.017590320429324603
# differential_evolution step 621: f(x)= 0.017590320429324603
# differential_evolution step 622: f(x)= 0.017590320429324603
# differential_evolution step 623: f(x)= 0.017590320429324603
# differential_evolution step 624: f(x)= 0.017590320429324603
# differential_evolution step 625: f(x)= 0.017590320429324603
# differential_evolution step 626: f(x)= 0.017590320429324603
# differential_evolution step 627: f(x)= 0.017590320429324603
# differential_evolution step 628: f(x)= 0.017590320429324603
# differential_evolution step 629: f(x)= 0.017590320429324603
# differential_evolution step 630: f(x)= 0.017590320429324603
# differential_evolution step 631: f(x)= 0.017590320429324603
# differential_evolution step 632: f(x)= 0.017590320429324603
# differential_evolution step 633: f(x)= 0.017590320429324603
# differential_evolution step 634: f(x)= 0.017590320429324603
# differential_evolution step 635: f(x)= 0.017590320429324603
# differential_evolution step 636: f(x)= 0.017590320429324603
# differential_evolution step 637: f(x)= 0.017590320429324603
# differential_evolution step 638: f(x)= 0.017590320429324603
# differential_evolution step 639: f(x)= 0.017590320429324603
# differential_evolution step 640: f(x)= 0.017590320429324603
# differential_evolution step 641: f(x)= 0.017590320429324603
# differential_evolution step 642: f(x)= 0.017590320429324603
# differential_evolution step 643: f(x)= 0.017590320429324603
# differential_evolution step 644: f(x)= 0.017590320429324603
# differential_evolution step 645: f(x)= 0.017590320429324603
# differential_evolution step 646: f(x)= 0.017380304720227717
# differential_evolution step 647: f(x)= 0.017380304720227717
# differential_evolution step 648: f(x)= 0.017380304720227717
# differential_evolution step 649: f(x)= 0.017380304720227717
# differential_evolution step 650: f(x)= 0.017380304720227717
# differential_evolution step 651: f(x)= 0.017380304720227717
# differential_evolution step 652: f(x)= 0.017380304720227717
# differential_evolution step 653: f(x)= 0.017380304720227717
# differential_evolution step 654: f(x)= 0.017380304720227717
# differential_evolution step 655: f(x)= 0.017380304720227717
# differential_evolution step 656: f(x)= 0.017380304720227717
# differential_evolution step 657: f(x)= 0.017380304720227717
# differential_evolution step 658: f(x)= 0.017380304720227717
# differential_evolution step 659: f(x)= 0.017380304720227717
# differential_evolution step 660: f(x)= 0.017380304720227717
# differential_evolution step 661: f(x)= 0.017380304720227717
# differential_evolution step 662: f(x)= 0.017380304720227717
# differential_evolution step 663: f(x)= 0.017380304720227717
# differential_evolution step 664: f(x)= 0.017380304720227717
# differential_evolution step 665: f(x)= 0.017380304720227717
# differential_evolution step 666: f(x)= 0.017380304720227717
# differential_evolution step 667: f(x)= 0.017380304720227717
# differential_evolution step 668: f(x)= 0.017380304720227717
# differential_evolution step 669: f(x)= 0.017380304720227717
# differential_evolution step 670: f(x)= 0.017380304720227717
# differential_evolution step 671: f(x)= 0.017380304720227717
# differential_evolution step 672: f(x)= 0.017380304720227717
# differential_evolution step 673: f(x)= 0.017380304720227717
# differential_evolution step 674: f(x)= 0.017380304720227717
# differential_evolution step 675: f(x)= 0.017380304720227717
# differential_evolution step 676: f(x)= 0.017380304720227717
# differential_evolution step 677: f(x)= 0.017380304720227717
# differential_evolution step 678: f(x)= 0.017380304720227717
# differential_evolution step 679: f(x)= 0.017380304720227717
# differential_evolution step 680: f(x)= 0.017380304720227717
# differential_evolution step 681: f(x)= 0.017380304720227717
# differential_evolution step 682: f(x)= 0.017380304720227717
# differential_evolution step 683: f(x)= 0.017380304720227717
# differential_evolution step 684: f(x)= 0.017380304720227717
# differential_evolution step 685: f(x)= 0.017380304720227717
# differential_evolution step 686: f(x)= 0.017380304720227717
# differential_evolution step 687: f(x)= 0.017380304720227717
# differential_evolution step 688: f(x)= 0.017380304720227717
# differential_evolution step 689: f(x)= 0.017143476772081598
# differential_evolution step 690: f(x)= 0.017143476772081598
# differential_evolution step 691: f(x)= 0.017143476772081598
# differential_evolution step 692: f(x)= 0.017143476772081598
# differential_evolution step 693: f(x)= 0.017143476772081598
# differential_evolution step 694: f(x)= 0.017143476772081598
# differential_evolution step 695: f(x)= 0.017143476772081598
# differential_evolution step 696: f(x)= 0.017143476772081598
# differential_evolution step 697: f(x)= 0.017143476772081598
# differential_evolution step 698: f(x)= 0.017143476772081598
# differential_evolution step 699: f(x)= 0.017143476772081598
# differential_evolution step 700: f(x)= 0.017143476772081598
# differential_evolution step 701: f(x)= 0.017143476772081598
# differential_evolution step 702: f(x)= 0.017143476772081598
# differential_evolution step 703: f(x)= 0.017143476772081598
# differential_evolution step 704: f(x)= 0.017143476772081598
# differential_evolution step 705: f(x)= 0.017143476772081598
# differential_evolution step 706: f(x)= 0.017143476772081598
# differential_evolution step 707: f(x)= 0.017143476772081598
# differential_evolution step 708: f(x)= 0.017143476772081598
# differential_evolution step 709: f(x)= 0.017143476772081598
# differential_evolution step 710: f(x)= 0.017143476772081598
# differential_evolution step 711: f(x)= 0.017143476772081598
# differential_evolution step 712: f(x)= 0.017143476772081598
# differential_evolution step 713: f(x)= 0.017143476772081598
# differential_evolution step 714: f(x)= 0.017143476772081598
# differential_evolution step 715: f(x)= 0.017143476772081598
# differential_evolution step 716: f(x)= 0.017143476772081598
# differential_evolution step 717: f(x)= 0.017143476772081598
# differential_evolution step 718: f(x)= 0.017143476772081598
# differential_evolution step 719: f(x)= 0.017143476772081598
# differential_evolution step 720: f(x)= 0.017143476772081598
# differential_evolution step 721: f(x)= 0.017143476772081598
# differential_evolution step 722: f(x)= 0.017143476772081598
# differential_evolution step 723: f(x)= 0.017143476772081598
# differential_evolution step 724: f(x)= 0.017143476772081598
# differential_evolution step 725: f(x)= 0.017143476772081598
# differential_evolution step 726: f(x)= 0.017143476772081598
# differential_evolution step 727: f(x)= 0.017143476772081598
# differential_evolution step 728: f(x)= 0.017143476772081598
# differential_evolution step 729: f(x)= 0.017143476772081598
# differential_evolution step 730: f(x)= 0.017143476772081598
# differential_evolution step 731: f(x)= 0.017143476772081598
# differential_evolution step 732: f(x)= 0.017143476772081598
# differential_evolution step 733: f(x)= 0.017143476772081598
# differential_evolution step 734: f(x)= 0.017143476772081598
# differential_evolution step 735: f(x)= 0.017143476772081598
# differential_evolution step 736: f(x)= 0.017143476772081598
# differential_evolution step 737: f(x)= 0.017143476772081598
# differential_evolution step 738: f(x)= 0.017143476772081598
# differential_evolution step 739: f(x)= 0.017143476772081598
# differential_evolution step 740: f(x)= 0.017143476772081598
# differential_evolution step 741: f(x)= 0.017143476772081598
# differential_evolution step 742: f(x)= 0.017143476772081598
# differential_evolution step 743: f(x)= 0.017143476772081598
# differential_evolution step 744: f(x)= 0.017143476772081598
# differential_evolution step 745: f(x)= 0.017143476772081598
# differential_evolution step 746: f(x)= 0.017143476772081598
# differential_evolution step 747: f(x)= 0.017143476772081598
# differential_evolution step 748: f(x)= 0.017143476772081598
# differential_evolution step 749: f(x)= 0.017143476772081598
# differential_evolution step 750: f(x)= 0.017143476772081598
# differential_evolution step 751: f(x)= 0.017143476772081598
# differential_evolution step 752: f(x)= 0.017143476772081598
# differential_evolution step 753: f(x)= 0.017143476772081598
# differential_evolution step 754: f(x)= 0.017143476772081598
# differential_evolution step 755: f(x)= 0.017143476772081598
# differential_evolution step 756: f(x)= 0.017143476772081598
# differential_evolution step 757: f(x)= 0.017143476772081598
# differential_evolution step 758: f(x)= 0.017143476772081598
# differential_evolution step 759: f(x)= 0.017143476772081598
# differential_evolution step 760: f(x)= 0.017143476772081598
# differential_evolution step 761: f(x)= 0.017143476772081598
# differential_evolution step 762: f(x)= 0.017143476772081598
# differential_evolution step 763: f(x)= 0.017143476772081598
# differential_evolution step 764: f(x)= 0.017143476772081598
# differential_evolution step 765: f(x)= 0.017143476772081598
# differential_evolution step 766: f(x)= 0.017143476772081598
# differential_evolution step 767: f(x)= 0.017143476772081598
# differential_evolution step 768: f(x)= 0.017143476772081598
# differential_evolution step 769: f(x)= 0.017143476772081598
# differential_evolution step 770: f(x)= 0.017143476772081598
# differential_evolution step 771: f(x)= 0.017143476772081598
# differential_evolution step 772: f(x)= 0.017143476772081598
# differential_evolution step 773: f(x)= 0.017143476772081598
# differential_evolution step 774: f(x)= 0.016848567513836985
# differential_evolution step 775: f(x)= 0.016848567513836985
# differential_evolution step 776: f(x)= 0.016848567513836985
# differential_evolution step 777: f(x)= 0.016848567513836985
# differential_evolution step 778: f(x)= 0.016848567513836985
# differential_evolution step 779: f(x)= 0.016848567513836985
# differential_evolution step 780: f(x)= 0.016848567513836985
# differential_evolution step 781: f(x)= 0.016848567513836985
# differential_evolution step 782: f(x)= 0.016848567513836985
# differential_evolution step 783: f(x)= 0.016848567513836985
# differential_evolution step 784: f(x)= 0.016848567513836985
# differential_evolution step 785: f(x)= 0.016848567513836985
# differential_evolution step 786: f(x)= 0.016848567513836985
# differential_evolution step 787: f(x)= 0.016848567513836985
# differential_evolution step 788: f(x)= 0.016848567513836985
# differential_evolution step 789: f(x)= 0.016848567513836985
# differential_evolution step 790: f(x)= 0.016848567513836985
# differential_evolution step 791: f(x)= 0.016848567513836985
# differential_evolution step 792: f(x)= 0.016848567513836985
# differential_evolution step 793: f(x)= 0.016689505342217924
# differential_evolution step 794: f(x)= 0.016689505342217924
# differential_evolution step 795: f(x)= 0.016689505342217924
# differential_evolution step 796: f(x)= 0.016689505342217924
# differential_evolution step 797: f(x)= 0.016689505342217924
# differential_evolution step 798: f(x)= 0.016689505342217924
# differential_evolution step 799: f(x)= 0.016689505342217924
# differential_evolution step 800: f(x)= 0.016689505342217924
# differential_evolution step 801: f(x)= 0.016689505342217924
# differential_evolution step 802: f(x)= 0.016689505342217924
# differential_evolution step 803: f(x)= 0.016689505342217924
# differential_evolution step 804: f(x)= 0.016689505342217924
# differential_evolution step 805: f(x)= 0.016689505342217924
# differential_evolution step 806: f(x)= 0.016689505342217924
# differential_evolution step 807: f(x)= 0.016689505342217924
# differential_evolution step 808: f(x)= 0.016689505342217924
# differential_evolution step 809: f(x)= 0.016689505342217924
# differential_evolution step 810: f(x)= 0.016689505342217924
# differential_evolution step 811: f(x)= 0.016689505342217924
# differential_evolution step 812: f(x)= 0.016689505342217924
# differential_evolution step 813: f(x)= 0.016689505342217924
# differential_evolution step 814: f(x)= 0.016689505342217924
# differential_evolution step 815: f(x)= 0.016689505342217924
# differential_evolution step 816: f(x)= 0.016689505342217924
# differential_evolution step 817: f(x)= 0.016689505342217924
# differential_evolution step 818: f(x)= 0.016689505342217924
# differential_evolution step 819: f(x)= 0.016689505342217924
# differential_evolution step 820: f(x)= 0.016689505342217924
# differential_evolution step 821: f(x)= 0.016689505342217924
# differential_evolution step 822: f(x)= 0.016689505342217924
# differential_evolution step 823: f(x)= 0.016689505342217924
# differential_evolution step 824: f(x)= 0.016689505342217924
# differential_evolution step 825: f(x)= 0.016689505342217924
# differential_evolution step 826: f(x)= 0.016689505342217924
# differential_evolution step 827: f(x)= 0.016689505342217924
# differential_evolution step 828: f(x)= 0.016689505342217924
# differential_evolution step 829: f(x)= 0.016689505342217924
# differential_evolution step 830: f(x)= 0.016689505342217924
# differential_evolution step 831: f(x)= 0.016689505342217924
# differential_evolution step 832: f(x)= 0.016689505342217924
# differential_evolution step 833: f(x)= 0.016689505342217924
# differential_evolution step 834: f(x)= 0.016689505342217924
# differential_evolution step 835: f(x)= 0.016689505342217924
# differential_evolution step 836: f(x)= 0.016689505342217924
# differential_evolution step 837: f(x)= 0.016689505342217924
# differential_evolution step 838: f(x)= 0.016689505342217924
# differential_evolution step 839: f(x)= 0.016689505342217924
# differential_evolution step 840: f(x)= 0.016689505342217924
# differential_evolution step 841: f(x)= 0.016689505342217924
# differential_evolution step 842: f(x)= 0.016689505342217924
# differential_evolution step 843: f(x)= 0.016689505342217924
# differential_evolution step 844: f(x)= 0.016689505342217924
# differential_evolution step 845: f(x)= 0.016689505342217924
# differential_evolution step 846: f(x)= 0.016689505342217924
# differential_evolution step 847: f(x)= 0.016689505342217924
# differential_evolution step 848: f(x)= 0.016689505342217924
# differential_evolution step 849: f(x)= 0.016689505342217924
# differential_evolution step 850: f(x)= 0.016689505342217924
# differential_evolution step 851: f(x)= 0.016689505342217924
# differential_evolution step 852: f(x)= 0.016689505342217924
# differential_evolution step 853: f(x)= 0.016689505342217924
# differential_evolution step 854: f(x)= 0.016689505342217924
# differential_evolution step 855: f(x)= 0.016689505342217924
# differential_evolution step 856: f(x)= 0.016689505342217924
# differential_evolution step 857: f(x)= 0.016689505342217924
# differential_evolution step 858: f(x)= 0.016689505342217924
# differential_evolution step 859: f(x)= 0.016689505342217924
# differential_evolution step 860: f(x)= 0.016689505342217924
# differential_evolution step 861: f(x)= 0.016689505342217924
# differential_evolution step 862: f(x)= 0.016689505342217924
# differential_evolution step 863: f(x)= 0.016689505342217924
# differential_evolution step 864: f(x)= 0.016689505342217924
# differential_evolution step 865: f(x)= 0.016689505342217924
# differential_evolution step 866: f(x)= 0.016689505342217924
# differential_evolution step 867: f(x)= 0.016689505342217924
# differential_evolution step 868: f(x)= 0.016689505342217924
# differential_evolution step 869: f(x)= 0.016689505342217924
# differential_evolution step 870: f(x)= 0.016689505342217924
# differential_evolution step 871: f(x)= 0.016689505342217924
# differential_evolution step 872: f(x)= 0.016689505342217924
# differential_evolution step 873: f(x)= 0.016689505342217924
# differential_evolution step 874: f(x)= 0.016689505342217924
# differential_evolution step 875: f(x)= 0.016689505342217924
# differential_evolution step 876: f(x)= 0.016689505342217924
# differential_evolution step 877: f(x)= 0.016689505342217924
# differential_evolution step 878: f(x)= 0.016689505342217924
# differential_evolution step 879: f(x)= 0.016689505342217924
# differential_evolution step 880: f(x)= 0.016689505342217924
# differential_evolution step 881: f(x)= 0.016689505342217924
# differential_evolution step 882: f(x)= 0.016689505342217924
# differential_evolution step 883: f(x)= 0.016689505342217924
# differential_evolution step 884: f(x)= 0.016689505342217924
# differential_evolution step 885: f(x)= 0.016689505342217924
# differential_evolution step 886: f(x)= 0.016689505342217924
# differential_evolution step 887: f(x)= 0.016689505342217924
# differential_evolution step 888: f(x)= 0.016689505342217924
# differential_evolution step 889: f(x)= 0.016689505342217924
# differential_evolution step 890: f(x)= 0.016689505342217924
# differential_evolution step 891: f(x)= 0.016689505342217924
# differential_evolution step 892: f(x)= 0.016689505342217924
# differential_evolution step 893: f(x)= 0.016689505342217924
# differential_evolution step 894: f(x)= 0.016689505342217924
# differential_evolution step 895: f(x)= 0.016689505342217924
# differential_evolution step 896: f(x)= 0.016689505342217924
# differential_evolution step 897: f(x)= 0.016689505342217924
# differential_evolution step 898: f(x)= 0.016689505342217924
# differential_evolution step 899: f(x)= 0.016689505342217924
# differential_evolution step 900: f(x)= 0.016689505342217924
# differential_evolution step 901: f(x)= 0.016689505342217924
# differential_evolution step 902: f(x)= 0.016689505342217924
# differential_evolution step 903: f(x)= 0.016689505342217924
# differential_evolution step 904: f(x)= 0.016689505342217924
# differential_evolution step 905: f(x)= 0.016689505342217924
# differential_evolution step 906: f(x)= 0.016689505342217924
# differential_evolution step 907: f(x)= 0.016689505342217924
# differential_evolution step 908: f(x)= 0.016689505342217924
# differential_evolution step 909: f(x)= 0.016689505342217924
# differential_evolution step 910: f(x)= 0.016689505342217924
# differential_evolution step 911: f(x)= 0.016689505342217924
# differential_evolution step 912: f(x)= 0.016689505342217924
# differential_evolution step 913: f(x)= 0.016689505342217924
# differential_evolution step 914: f(x)= 0.016689505342217924
# differential_evolution step 915: f(x)= 0.016689505342217924
# differential_evolution step 916: f(x)= 0.016689505342217924
# differential_evolution step 917: f(x)= 0.016689505342217924
# differential_evolution step 918: f(x)= 0.016689505342217924
# differential_evolution step 919: f(x)= 0.016689505342217924
# differential_evolution step 920: f(x)= 0.016689505342217924
# differential_evolution step 921: f(x)= 0.016689505342217924
# differential_evolution step 922: f(x)= 0.016689505342217924
# differential_evolution step 923: f(x)= 0.016689505342217924
# differential_evolution step 924: f(x)= 0.016689505342217924
# differential_evolution step 925: f(x)= 0.016689505342217924
# differential_evolution step 926: f(x)= 0.016689505342217924
# differential_evolution step 927: f(x)= 0.016689505342217924
# differential_evolution step 928: f(x)= 0.016689505342217924
# differential_evolution step 929: f(x)= 0.016689505342217924
# differential_evolution step 930: f(x)= 0.016689505342217924
# differential_evolution step 931: f(x)= 0.016689505342217924
# differential_evolution step 932: f(x)= 0.016689505342217924
# differential_evolution step 933: f(x)= 0.016689505342217924
# differential_evolution step 934: f(x)= 0.016689505342217924
# differential_evolution step 935: f(x)= 0.016689505342217924
# differential_evolution step 936: f(x)= 0.016689505342217924
# differential_evolution step 937: f(x)= 0.016689505342217924
# differential_evolution step 938: f(x)= 0.016689505342217924
# differential_evolution step 939: f(x)= 0.016689505342217924
# differential_evolution step 940: f(x)= 0.016689505342217924
# differential_evolution step 941: f(x)= 0.016689505342217924
# differential_evolution step 942: f(x)= 0.016689505342217924
# differential_evolution step 943: f(x)= 0.016689505342217924
# differential_evolution step 944: f(x)= 0.016689505342217924
# differential_evolution step 945: f(x)= 0.016689505342217924
# differential_evolution step 946: f(x)= 0.016689505342217924
# differential_evolution step 947: f(x)= 0.016689505342217924
# differential_evolution step 948: f(x)= 0.016689505342217924
# differential_evolution step 949: f(x)= 0.016689505342217924
# differential_evolution step 950: f(x)= 0.016689505342217924
# differential_evolution step 951: f(x)= 0.016689505342217924
# differential_evolution step 952: f(x)= 0.016689505342217924
# differential_evolution step 953: f(x)= 0.016689505342217924
# differential_evolution step 954: f(x)= 0.016689505342217924
# differential_evolution step 955: f(x)= 0.016689505342217924
# differential_evolution step 956: f(x)= 0.016689505342217924
# differential_evolution step 957: f(x)= 0.016689505342217924
# differential_evolution step 958: f(x)= 0.016689505342217924
# differential_evolution step 959: f(x)= 0.016689505342217924
# differential_evolution step 960: f(x)= 0.016689505342217924
# differential_evolution step 961: f(x)= 0.016689505342217924
# differential_evolution step 962: f(x)= 0.016689505342217924
# differential_evolution step 963: f(x)= 0.016689505342217924
# differential_evolution step 964: f(x)= 0.016689505342217924
# differential_evolution step 965: f(x)= 0.016689505342217924
# differential_evolution step 966: f(x)= 0.016689505342217924
# differential_evolution step 967: f(x)= 0.016689505342217924
# differential_evolution step 968: f(x)= 0.016689505342217924
# differential_evolution step 969: f(x)= 0.016689505342217924
# differential_evolution step 970: f(x)= 0.016689505342217924
# differential_evolution step 971: f(x)= 0.016689505342217924
# differential_evolution step 972: f(x)= 0.016689505342217924
# differential_evolution step 973: f(x)= 0.016689505342217924
# differential_evolution step 974: f(x)= 0.016689505342217924
# differential_evolution step 975: f(x)= 0.016689505342217924
# differential_evolution step 976: f(x)= 0.016689505342217924
# differential_evolution step 977: f(x)= 0.016689505342217924
# differential_evolution step 978: f(x)= 0.016689505342217924
# differential_evolution step 979: f(x)= 0.016689505342217924
# differential_evolution step 980: f(x)= 0.016689505342217924
# differential_evolution step 981: f(x)= 0.016689505342217924
# differential_evolution step 982: f(x)= 0.016689505342217924
# differential_evolution step 983: f(x)= 0.016689505342217924
# differential_evolution step 984: f(x)= 0.016689505342217924
# differential_evolution step 985: f(x)= 0.016668887730518656
# differential_evolution step 986: f(x)= 0.016668887730518656
# differential_evolution step 987: f(x)= 0.016668887730518656
# differential_evolution step 988: f(x)= 0.016668887730518656
# differential_evolution step 989: f(x)= 0.016668887730518656
# differential_evolution step 990: f(x)= 0.016638058258198828
# differential_evolution step 991: f(x)= 0.016638058258198828
# differential_evolution step 992: f(x)= 0.016638058258198828
# differential_evolution step 993: f(x)= 0.016638058258198828
# differential_evolution step 994: f(x)= 0.016638058258198828
# differential_evolution step 995: f(x)= 0.016638058258198828
# differential_evolution step 996: f(x)= 0.016638058258198828
# differential_evolution step 997: f(x)= 0.016638058258198828
# differential_evolution step 998: f(x)= 0.016638058258198828
# differential_evolution step 999: f(x)= 0.016638058258198828
# differential_evolution step 1000: f(x)= 0.016638058258198828
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.0125, r_e=37.1880, n=2.1851, x_0=27.2814
# Sérsic 2: I_e=0.0867, r_e=13.6555, n=0.4413, x_0=50.5337
# Sérsic 3: I_e=0.6499, r_e=0.5097, n=2.4099, x_0=61.2408
# Sérsic 4: I_e=0.0181, r_e=16.2374, n=1.3522, x_0=68.4174
# Sérsic 5: I_e=0.0213, r_e=19.7190, n=0.6409, x_0=103.2133
# Chi quadro minimo: 0.01631785456489824
# False

# %%
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Sérsic 1: I_e=0.0125, r_e=37.1880, n=2.1851, x_0=27.2814
# Sérsic 2: I_e=0.0867, r_e=13.6555, n=0.4413, x_0=50.5337
# Sérsic 3: I_e=0.6499, r_e=0.5097, n=2.4099, x_0=61.2408
# Sérsic 4: I_e=0.0181, r_e=16.2374, n=1.3522, x_0=68.4174
# Sérsic 5: I_e=0.0213, r_e=19.7190, n=0.6409, x_0=103.2133
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = real_errors_NII)#, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0118, r_e=36.2561, n=2.2078, x_0=27.3786
# Sérsic 2: I_e=0.0874, r_e=16.5367, n=0.4833, x_0=53.4352
# Sérsic 3: I_e=0.6373, r_e=0.4253, n=2.5612, x_0=61.2408
# Sérsic 4: I_e=0.0173, r_e=4.3524, n=1.4829, x_0=68.5078
# Sérsic 5: I_e=0.0079, r_e=62.1246, n=1.2323, x_0=102.6025
# [1.20761165e-02 3.25377326e+01 6.73186160e-01 1.26553091e-01
#  6.71985604e-02 3.36051888e+00 3.46874961e-01 9.43031007e+00
#  2.06020514e+01 4.50636332e+00 2.80716217e+01 5.29116474e-02
#  1.74259532e-01 3.82931858e+01 7.65472027e+00 5.22361857e-01
#  1.95353720e-02 1.88863244e+02 1.39258516e+00 1.53332352e+00]
# 0.12117398468413342

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))
real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[2])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 42496.4305998913
# differential_evolution step 2: f(x)= 19100.60312719336
# differential_evolution step 3: f(x)= 748.778625333674
# differential_evolution step 4: f(x)= 748.778625333674
# differential_evolution step 5: f(x)= 748.778625333674
# differential_evolution step 6: f(x)= 748.778625333674
# differential_evolution step 7: f(x)= 748.778625333674
# differential_evolution step 8: f(x)= 748.778625333674
# differential_evolution step 9: f(x)= 748.778625333674
# differential_evolution step 10: f(x)= 748.778625333674
# differential_evolution step 11: f(x)= 249.8978562142517
# differential_evolution step 12: f(x)= 249.8978562142517
# differential_evolution step 13: f(x)= 249.8978562142517
# differential_evolution step 14: f(x)= 249.8978562142517
# differential_evolution step 15: f(x)= 249.8978562142517
# differential_evolution step 16: f(x)= 249.8978562142517
# differential_evolution step 17: f(x)= 249.8978562142517
# differential_evolution step 18: f(x)= 249.8978562142517
# differential_evolution step 19: f(x)= 249.8978562142517
# differential_evolution step 20: f(x)= 249.8978562142517
# differential_evolution step 21: f(x)= 210.28968533466212
# differential_evolution step 22: f(x)= 170.3455455015594
# differential_evolution step 23: f(x)= 170.3455455015594
# differential_evolution step 24: f(x)= 92.98066485134552
# differential_evolution step 25: f(x)= 92.98066485134552
# differential_evolution step 26: f(x)= 92.98066485134552
# differential_evolution step 27: f(x)= 85.13072219222731
# differential_evolution step 28: f(x)= 85.13072219222731
# differential_evolution step 29: f(x)= 40.52002567782688
# differential_evolution step 30: f(x)= 40.52002567782688
# differential_evolution step 31: f(x)= 40.52002567782688
# differential_evolution step 32: f(x)= 40.52002567782688
# differential_evolution step 33: f(x)= 40.52002567782688
# differential_evolution step 34: f(x)= 40.52002567782688
# differential_evolution step 35: f(x)= 40.52002567782688
# differential_evolution step 36: f(x)= 40.52002567782688
# differential_evolution step 37: f(x)= 40.52002567782688
# differential_evolution step 38: f(x)= 40.52002567782688
# differential_evolution step 39: f(x)= 40.52002567782688
# differential_evolution step 40: f(x)= 33.84204279296661
# differential_evolution step 41: f(x)= 33.84204279296661
# differential_evolution step 42: f(x)= 33.84204279296661
# differential_evolution step 43: f(x)= 33.84204279296661
# differential_evolution step 44: f(x)= 33.84204279296661
# differential_evolution step 45: f(x)= 32.89002034644308
# differential_evolution step 46: f(x)= 21.853860692517515
# differential_evolution step 47: f(x)= 20.455669743462373
# differential_evolution step 48: f(x)= 20.455669743462373
# differential_evolution step 49: f(x)= 20.455669743462373
# differential_evolution step 50: f(x)= 2.7067944377525843
# differential_evolution step 51: f(x)= 2.7067944377525843
# differential_evolution step 52: f(x)= 2.7067944377525843
# differential_evolution step 53: f(x)= 2.7067944377525843
# differential_evolution step 54: f(x)= 2.7067944377525843
# differential_evolution step 55: f(x)= 2.7067944377525843
# differential_evolution step 56: f(x)= 2.7067944377525843
# differential_evolution step 57: f(x)= 2.7067944377525843
# differential_evolution step 58: f(x)= 2.7067944377525843
# differential_evolution step 59: f(x)= 2.7067944377525843
# differential_evolution step 60: f(x)= 2.7067944377525843
# differential_evolution step 61: f(x)= 2.1717137355825953
# differential_evolution step 62: f(x)= 2.1717137355825953
# differential_evolution step 63: f(x)= 2.1717137355825953
# differential_evolution step 64: f(x)= 2.1717137355825953
# differential_evolution step 65: f(x)= 2.1717137355825953
# differential_evolution step 66: f(x)= 2.1717137355825953
# differential_evolution step 67: f(x)= 1.3896878055525117
# differential_evolution step 68: f(x)= 1.3896878055525117
# differential_evolution step 69: f(x)= 1.3896878055525117
# differential_evolution step 70: f(x)= 1.3896878055525117
# differential_evolution step 71: f(x)= 1.3896878055525117
# differential_evolution step 72: f(x)= 1.3896878055525117
# differential_evolution step 73: f(x)= 1.3896878055525117
# differential_evolution step 74: f(x)= 1.3896878055525117
# differential_evolution step 75: f(x)= 1.3102616122733337
# differential_evolution step 76: f(x)= 1.3102616122733337
# differential_evolution step 77: f(x)= 1.3102616122733337
# differential_evolution step 78: f(x)= 1.3102616122733337
# differential_evolution step 79: f(x)= 1.3102616122733337
# differential_evolution step 80: f(x)= 1.3102616122733337
# differential_evolution step 81: f(x)= 1.3102616122733337
# differential_evolution step 82: f(x)= 1.3102616122733337
# differential_evolution step 83: f(x)= 1.3102616122733337
# differential_evolution step 84: f(x)= 1.2079763167586126
# differential_evolution step 85: f(x)= 1.2079763167586126
# differential_evolution step 86: f(x)= 1.2079763167586126
# differential_evolution step 87: f(x)= 1.2079763167586126
# differential_evolution step 88: f(x)= 0.9591001375660055
# differential_evolution step 89: f(x)= 0.9591001375660055
# differential_evolution step 90: f(x)= 0.9520759274448993
# differential_evolution step 91: f(x)= 0.9520759274448993
# differential_evolution step 92: f(x)= 0.9520759274448993
# differential_evolution step 93: f(x)= 0.9520759274448993
# differential_evolution step 94: f(x)= 0.9520759274448993
# differential_evolution step 95: f(x)= 0.9520759274448993
# differential_evolution step 96: f(x)= 0.3620868142052197
# differential_evolution step 97: f(x)= 0.3620868142052197
# differential_evolution step 98: f(x)= 0.3620868142052197
# differential_evolution step 99: f(x)= 0.3620868142052197
# differential_evolution step 100: f(x)= 0.3620868142052197
# differential_evolution step 101: f(x)= 0.3620868142052197
# differential_evolution step 102: f(x)= 0.3620868142052197
# differential_evolution step 103: f(x)= 0.3620868142052197
# differential_evolution step 104: f(x)= 0.3620868142052197
# differential_evolution step 105: f(x)= 0.3620868142052197
# differential_evolution step 106: f(x)= 0.3620868142052197
# differential_evolution step 107: f(x)= 0.3620868142052197
# differential_evolution step 108: f(x)= 0.3620868142052197
# differential_evolution step 109: f(x)= 0.3620868142052197
# differential_evolution step 110: f(x)= 0.3620868142052197
# differential_evolution step 111: f(x)= 0.3620868142052197
# differential_evolution step 112: f(x)= 0.3620868142052197
# differential_evolution step 113: f(x)= 0.3620868142052197
# differential_evolution step 114: f(x)= 0.3620868142052197
# differential_evolution step 115: f(x)= 0.3620868142052197
# differential_evolution step 116: f(x)= 0.3620868142052197
# differential_evolution step 117: f(x)= 0.3620868142052197
# differential_evolution step 118: f(x)= 0.3620868142052197
# differential_evolution step 119: f(x)= 0.3620868142052197
# differential_evolution step 120: f(x)= 0.3620868142052197
# differential_evolution step 121: f(x)= 0.3620868142052197
# differential_evolution step 122: f(x)= 0.3620868142052197
# differential_evolution step 123: f(x)= 0.3620868142052197
# differential_evolution step 124: f(x)= 0.279919983509196
# differential_evolution step 125: f(x)= 0.279919983509196
# differential_evolution step 126: f(x)= 0.279919983509196
# differential_evolution step 127: f(x)= 0.279919983509196
# differential_evolution step 128: f(x)= 0.279919983509196
# differential_evolution step 129: f(x)= 0.279919983509196
# differential_evolution step 130: f(x)= 0.279919983509196
# differential_evolution step 131: f(x)= 0.279919983509196
# differential_evolution step 132: f(x)= 0.279919983509196
# differential_evolution step 133: f(x)= 0.26463836597341917
# differential_evolution step 134: f(x)= 0.17493230606852772
# differential_evolution step 135: f(x)= 0.17493230606852772
# differential_evolution step 136: f(x)= 0.17493230606852772
# differential_evolution step 137: f(x)= 0.17493230606852772
# differential_evolution step 138: f(x)= 0.17493230606852772
# differential_evolution step 139: f(x)= 0.17493230606852772
# differential_evolution step 140: f(x)= 0.17493230606852772
# differential_evolution step 141: f(x)= 0.17493230606852772
# differential_evolution step 142: f(x)= 0.17493230606852772
# differential_evolution step 143: f(x)= 0.17493230606852772
# differential_evolution step 144: f(x)= 0.17493230606852772
# differential_evolution step 145: f(x)= 0.17493230606852772
# differential_evolution step 146: f(x)= 0.17493230606852772
# differential_evolution step 147: f(x)= 0.17493230606852772
# differential_evolution step 148: f(x)= 0.17493230606852772
# differential_evolution step 149: f(x)= 0.17493230606852772
# differential_evolution step 150: f(x)= 0.17493230606852772
# differential_evolution step 151: f(x)= 0.1522696531406768
# differential_evolution step 152: f(x)= 0.1522696531406768
# differential_evolution step 153: f(x)= 0.1522696531406768
# differential_evolution step 154: f(x)= 0.14546257528329007
# differential_evolution step 155: f(x)= 0.14546257528329007
# differential_evolution step 156: f(x)= 0.14546257528329007
# differential_evolution step 157: f(x)= 0.14546257528329007
# differential_evolution step 158: f(x)= 0.14546257528329007
# differential_evolution step 159: f(x)= 0.14546257528329007
# differential_evolution step 160: f(x)= 0.14546257528329007
# differential_evolution step 161: f(x)= 0.14546257528329007
# differential_evolution step 162: f(x)= 0.14546257528329007
# differential_evolution step 163: f(x)= 0.11825414126805452
# differential_evolution step 164: f(x)= 0.11825414126805452
# differential_evolution step 165: f(x)= 0.11825414126805452
# differential_evolution step 166: f(x)= 0.11825414126805452
# differential_evolution step 167: f(x)= 0.09090460950273
# differential_evolution step 168: f(x)= 0.09090460950273
# differential_evolution step 169: f(x)= 0.09090460950273
# differential_evolution step 170: f(x)= 0.09090460950273
# differential_evolution step 171: f(x)= 0.09090460950273
# differential_evolution step 172: f(x)= 0.09090460950273
# differential_evolution step 173: f(x)= 0.09090460950273
# differential_evolution step 174: f(x)= 0.09090460950273
# differential_evolution step 175: f(x)= 0.09090460950273
# differential_evolution step 176: f(x)= 0.09090460950273
# differential_evolution step 177: f(x)= 0.09090460950273
# differential_evolution step 178: f(x)= 0.09090460950273
# differential_evolution step 179: f(x)= 0.09090460950273
# differential_evolution step 180: f(x)= 0.09090460950273
# differential_evolution step 181: f(x)= 0.09090460950273
# differential_evolution step 182: f(x)= 0.09090460950273
# differential_evolution step 183: f(x)= 0.09090460950273
# differential_evolution step 184: f(x)= 0.09090460950273
# differential_evolution step 185: f(x)= 0.09090460950273
# differential_evolution step 186: f(x)= 0.08105375430302998
# differential_evolution step 187: f(x)= 0.08105375430302998
# differential_evolution step 188: f(x)= 0.08105375430302998
# differential_evolution step 189: f(x)= 0.08105375430302998
# differential_evolution step 190: f(x)= 0.08105375430302998
# differential_evolution step 191: f(x)= 0.08105375430302998
# differential_evolution step 192: f(x)= 0.08105375430302998
# differential_evolution step 193: f(x)= 0.08105375430302998
# differential_evolution step 194: f(x)= 0.08105375430302998
# differential_evolution step 195: f(x)= 0.08105375430302998
# differential_evolution step 196: f(x)= 0.08105375430302998
# differential_evolution step 197: f(x)= 0.07196372577979979
# differential_evolution step 198: f(x)= 0.07196372577979979
# differential_evolution step 199: f(x)= 0.07196372577979979
# differential_evolution step 200: f(x)= 0.07196372577979979
# differential_evolution step 201: f(x)= 0.07196372577979979
# differential_evolution step 202: f(x)= 0.07196372577979979
# differential_evolution step 203: f(x)= 0.07196372577979979
# differential_evolution step 204: f(x)= 0.07196372577979979
# differential_evolution step 205: f(x)= 0.07196372577979979
# differential_evolution step 206: f(x)= 0.07196372577979979
# differential_evolution step 207: f(x)= 0.07196372577979979
# differential_evolution step 208: f(x)= 0.07196372577979979
# differential_evolution step 209: f(x)= 0.07196372577979979
# differential_evolution step 210: f(x)= 0.07196372577979979
# differential_evolution step 211: f(x)= 0.07196372577979979
# differential_evolution step 212: f(x)= 0.07196372577979979
# differential_evolution step 213: f(x)= 0.06484873155039468
# differential_evolution step 214: f(x)= 0.06484873155039468
# differential_evolution step 215: f(x)= 0.06484873155039468
# differential_evolution step 216: f(x)= 0.06484873155039468
# differential_evolution step 217: f(x)= 0.06484873155039468
# differential_evolution step 218: f(x)= 0.06358909886433861
# differential_evolution step 219: f(x)= 0.06358909886433861
# differential_evolution step 220: f(x)= 0.06358909886433861
# differential_evolution step 221: f(x)= 0.06358909886433861
# differential_evolution step 222: f(x)= 0.06358909886433861
# differential_evolution step 223: f(x)= 0.06358909886433861
# differential_evolution step 224: f(x)= 0.06358909886433861
# differential_evolution step 225: f(x)= 0.06358909886433861
# differential_evolution step 226: f(x)= 0.06358909886433861
# differential_evolution step 227: f(x)= 0.06358909886433861
# differential_evolution step 228: f(x)= 0.06358909886433861
# differential_evolution step 229: f(x)= 0.06350582310278335
# differential_evolution step 230: f(x)= 0.06350582310278335
# differential_evolution step 231: f(x)= 0.06350582310278335
# differential_evolution step 232: f(x)= 0.06350582310278335
# differential_evolution step 233: f(x)= 0.06350582310278335
# differential_evolution step 234: f(x)= 0.06350582310278335
# differential_evolution step 235: f(x)= 0.06350582310278335
# differential_evolution step 236: f(x)= 0.06350582310278335
# differential_evolution step 237: f(x)= 0.05714226230021499
# differential_evolution step 238: f(x)= 0.05714226230021499
# differential_evolution step 239: f(x)= 0.05714226230021499
# differential_evolution step 240: f(x)= 0.05714226230021499
# differential_evolution step 241: f(x)= 0.05714226230021499
# differential_evolution step 242: f(x)= 0.05714226230021499
# differential_evolution step 243: f(x)= 0.05714226230021499
# differential_evolution step 244: f(x)= 0.05714226230021499
# differential_evolution step 245: f(x)= 0.05714226230021499
# differential_evolution step 246: f(x)= 0.05714226230021499
# differential_evolution step 247: f(x)= 0.05714226230021499
# differential_evolution step 248: f(x)= 0.05714226230021499
# differential_evolution step 249: f(x)= 0.05714226230021499
# differential_evolution step 250: f(x)= 0.05714226230021499
# differential_evolution step 251: f(x)= 0.05714226230021499
# differential_evolution step 252: f(x)= 0.05714226230021499
# differential_evolution step 253: f(x)= 0.05714226230021499
# differential_evolution step 254: f(x)= 0.05714226230021499
# differential_evolution step 255: f(x)= 0.05714226230021499
# differential_evolution step 256: f(x)= 0.05714226230021499
# differential_evolution step 257: f(x)= 0.05714226230021499
# differential_evolution step 258: f(x)= 0.05714226230021499
# differential_evolution step 259: f(x)= 0.05714226230021499
# differential_evolution step 260: f(x)= 0.04583329387472927
# differential_evolution step 261: f(x)= 0.04583329387472927
# differential_evolution step 262: f(x)= 0.04583329387472927
# differential_evolution step 263: f(x)= 0.04583329387472927
# differential_evolution step 264: f(x)= 0.04583329387472927
# differential_evolution step 265: f(x)= 0.04583329387472927
# differential_evolution step 266: f(x)= 0.04583329387472927
# differential_evolution step 267: f(x)= 0.04583329387472927
# differential_evolution step 268: f(x)= 0.04583329387472927
# differential_evolution step 269: f(x)= 0.04583329387472927
# differential_evolution step 270: f(x)= 0.04583329387472927
# differential_evolution step 271: f(x)= 0.04583329387472927
# differential_evolution step 272: f(x)= 0.04583329387472927
# differential_evolution step 273: f(x)= 0.04583329387472927
# differential_evolution step 274: f(x)= 0.04583329387472927
# differential_evolution step 275: f(x)= 0.04583329387472927
# differential_evolution step 276: f(x)= 0.04583329387472927
# differential_evolution step 277: f(x)= 0.04583329387472927
# differential_evolution step 278: f(x)= 0.04583329387472927
# differential_evolution step 279: f(x)= 0.04583329387472927
# differential_evolution step 280: f(x)= 0.04583329387472927
# differential_evolution step 281: f(x)= 0.04583329387472927
# differential_evolution step 282: f(x)= 0.04583329387472927
# differential_evolution step 283: f(x)= 0.04583329387472927
# differential_evolution step 284: f(x)= 0.04583329387472927
# differential_evolution step 285: f(x)= 0.04583329387472927
# differential_evolution step 286: f(x)= 0.04583329387472927
# differential_evolution step 287: f(x)= 0.04583329387472927
# differential_evolution step 288: f(x)= 0.04583329387472927
# differential_evolution step 289: f(x)= 0.04583329387472927
# differential_evolution step 290: f(x)= 0.04583329387472927
# differential_evolution step 291: f(x)= 0.04583329387472927
# differential_evolution step 292: f(x)= 0.04583329387472927
# differential_evolution step 293: f(x)= 0.04583329387472927
# differential_evolution step 294: f(x)= 0.04583329387472927
# differential_evolution step 295: f(x)= 0.04583329387472927
# differential_evolution step 296: f(x)= 0.04583329387472927
# differential_evolution step 297: f(x)= 0.04583329387472927
# differential_evolution step 298: f(x)= 0.04583329387472927
# differential_evolution step 299: f(x)= 0.04583329387472927
# differential_evolution step 300: f(x)= 0.04583329387472927
# differential_evolution step 301: f(x)= 0.04583329387472927
# differential_evolution step 302: f(x)= 0.04583329387472927
# differential_evolution step 303: f(x)= 0.04583329387472927
# differential_evolution step 304: f(x)= 0.04583329387472927
# differential_evolution step 305: f(x)= 0.04583329387472927
# differential_evolution step 306: f(x)= 0.04583329387472927
# differential_evolution step 307: f(x)= 0.04583329387472927
# differential_evolution step 308: f(x)= 0.04583329387472927
# differential_evolution step 309: f(x)= 0.04583329387472927
# differential_evolution step 310: f(x)= 0.04583329387472927
# differential_evolution step 311: f(x)= 0.04583329387472927
# differential_evolution step 312: f(x)= 0.045213910103167144
# differential_evolution step 313: f(x)= 0.045213910103167144
# differential_evolution step 314: f(x)= 0.045213910103167144
# differential_evolution step 315: f(x)= 0.045213910103167144
# differential_evolution step 316: f(x)= 0.045213910103167144
# differential_evolution step 317: f(x)= 0.045213910103167144
# differential_evolution step 318: f(x)= 0.045213910103167144
# differential_evolution step 319: f(x)= 0.045213910103167144
# differential_evolution step 320: f(x)= 0.045213910103167144
# differential_evolution step 321: f(x)= 0.045213910103167144
# differential_evolution step 322: f(x)= 0.045213910103167144
# differential_evolution step 323: f(x)= 0.045213910103167144
# differential_evolution step 324: f(x)= 0.045213910103167144
# differential_evolution step 325: f(x)= 0.045213910103167144
# differential_evolution step 326: f(x)= 0.045213910103167144
# differential_evolution step 327: f(x)= 0.045213910103167144
# differential_evolution step 328: f(x)= 0.045213910103167144
# differential_evolution step 329: f(x)= 0.045213910103167144
# differential_evolution step 330: f(x)= 0.045213910103167144
# differential_evolution step 331: f(x)= 0.045213910103167144
# differential_evolution step 332: f(x)= 0.045213910103167144
# differential_evolution step 333: f(x)= 0.045213910103167144
# differential_evolution step 334: f(x)= 0.045213910103167144
# differential_evolution step 335: f(x)= 0.04459238369847219
# differential_evolution step 336: f(x)= 0.04459238369847219
# differential_evolution step 337: f(x)= 0.04459238369847219
# differential_evolution step 338: f(x)= 0.04459238369847219
# differential_evolution step 339: f(x)= 0.04459238369847219
# differential_evolution step 340: f(x)= 0.04459238369847219
# differential_evolution step 341: f(x)= 0.04283029056168891
# differential_evolution step 342: f(x)= 0.04283029056168891
# differential_evolution step 343: f(x)= 0.04283029056168891
# differential_evolution step 344: f(x)= 0.04283029056168891
# differential_evolution step 345: f(x)= 0.04283029056168891
# differential_evolution step 346: f(x)= 0.04283029056168891
# differential_evolution step 347: f(x)= 0.04283029056168891
# differential_evolution step 348: f(x)= 0.04283029056168891
# differential_evolution step 349: f(x)= 0.04283029056168891
# differential_evolution step 350: f(x)= 0.04283029056168891
# differential_evolution step 351: f(x)= 0.04283029056168891
# differential_evolution step 352: f(x)= 0.04283029056168891
# differential_evolution step 353: f(x)= 0.04283029056168891
# differential_evolution step 354: f(x)= 0.04283029056168891
# differential_evolution step 355: f(x)= 0.04283029056168891
# differential_evolution step 356: f(x)= 0.04283029056168891
# differential_evolution step 357: f(x)= 0.04283029056168891
# differential_evolution step 358: f(x)= 0.04283029056168891
# differential_evolution step 359: f(x)= 0.04283029056168891
# differential_evolution step 360: f(x)= 0.04283029056168891
# differential_evolution step 361: f(x)= 0.04283029056168891
# differential_evolution step 362: f(x)= 0.04283029056168891
# differential_evolution step 363: f(x)= 0.04283029056168891
# differential_evolution step 364: f(x)= 0.04283029056168891
# differential_evolution step 365: f(x)= 0.04283029056168891
# differential_evolution step 366: f(x)= 0.04283029056168891
# differential_evolution step 367: f(x)= 0.04283029056168891
# differential_evolution step 368: f(x)= 0.04283029056168891
# differential_evolution step 369: f(x)= 0.04283029056168891
# differential_evolution step 370: f(x)= 0.04283029056168891
# differential_evolution step 371: f(x)= 0.04283029056168891
# differential_evolution step 372: f(x)= 0.04283029056168891
# differential_evolution step 373: f(x)= 0.04283029056168891
# differential_evolution step 374: f(x)= 0.04283029056168891
# differential_evolution step 375: f(x)= 0.04283029056168891
# differential_evolution step 376: f(x)= 0.04283029056168891
# differential_evolution step 377: f(x)= 0.04283029056168891
# differential_evolution step 378: f(x)= 0.04283029056168891
# differential_evolution step 379: f(x)= 0.04283029056168891
# differential_evolution step 380: f(x)= 0.04283029056168891
# differential_evolution step 381: f(x)= 0.04283029056168891
# differential_evolution step 382: f(x)= 0.04283029056168891
# differential_evolution step 383: f(x)= 0.04283029056168891
# differential_evolution step 384: f(x)= 0.04283029056168891
# differential_evolution step 385: f(x)= 0.04283029056168891
# differential_evolution step 386: f(x)= 0.041931237998771936
# differential_evolution step 387: f(x)= 0.041931237998771936
# differential_evolution step 388: f(x)= 0.041931237998771936
# differential_evolution step 389: f(x)= 0.041931237998771936
# differential_evolution step 390: f(x)= 0.041931237998771936
# differential_evolution step 391: f(x)= 0.041931237998771936
# differential_evolution step 392: f(x)= 0.041931237998771936
# differential_evolution step 393: f(x)= 0.041931237998771936
# differential_evolution step 394: f(x)= 0.041931237998771936
# differential_evolution step 395: f(x)= 0.041931237998771936
# differential_evolution step 396: f(x)= 0.041931237998771936
# differential_evolution step 397: f(x)= 0.041931237998771936
# differential_evolution step 398: f(x)= 0.041931237998771936
# differential_evolution step 399: f(x)= 0.041931237998771936
# differential_evolution step 400: f(x)= 0.041931237998771936
# differential_evolution step 401: f(x)= 0.041931237998771936
# differential_evolution step 402: f(x)= 0.041931237998771936
# differential_evolution step 403: f(x)= 0.041931237998771936
# differential_evolution step 404: f(x)= 0.041931237998771936
# differential_evolution step 405: f(x)= 0.041931237998771936
# differential_evolution step 406: f(x)= 0.041931237998771936
# differential_evolution step 407: f(x)= 0.041931237998771936
# differential_evolution step 408: f(x)= 0.041931237998771936
# differential_evolution step 409: f(x)= 0.041931237998771936
# differential_evolution step 410: f(x)= 0.041931237998771936
# differential_evolution step 411: f(x)= 0.041931237998771936
# differential_evolution step 412: f(x)= 0.041931237998771936
# differential_evolution step 413: f(x)= 0.041931237998771936
# differential_evolution step 414: f(x)= 0.041931237998771936
# differential_evolution step 415: f(x)= 0.041931237998771936
# differential_evolution step 416: f(x)= 0.041931237998771936
# differential_evolution step 417: f(x)= 0.041931237998771936
# differential_evolution step 418: f(x)= 0.041931237998771936
# differential_evolution step 419: f(x)= 0.041931237998771936
# differential_evolution step 420: f(x)= 0.041931237998771936
# differential_evolution step 421: f(x)= 0.041931237998771936
# differential_evolution step 422: f(x)= 0.041931237998771936
# differential_evolution step 423: f(x)= 0.041931237998771936
# differential_evolution step 424: f(x)= 0.04128683057798872
# differential_evolution step 425: f(x)= 0.04128683057798872
# differential_evolution step 426: f(x)= 0.04128683057798872
# differential_evolution step 427: f(x)= 0.041007978640038294
# differential_evolution step 428: f(x)= 0.041007978640038294
# differential_evolution step 429: f(x)= 0.041007978640038294
# differential_evolution step 430: f(x)= 0.041007978640038294
# differential_evolution step 431: f(x)= 0.041007978640038294
# differential_evolution step 432: f(x)= 0.041007978640038294
# differential_evolution step 433: f(x)= 0.041007978640038294
# differential_evolution step 434: f(x)= 0.041007978640038294
# differential_evolution step 435: f(x)= 0.041007978640038294
# differential_evolution step 436: f(x)= 0.041007978640038294
# differential_evolution step 437: f(x)= 0.041007978640038294
# differential_evolution step 438: f(x)= 0.041007978640038294
# differential_evolution step 439: f(x)= 0.041007978640038294
# differential_evolution step 440: f(x)= 0.041007978640038294
# differential_evolution step 441: f(x)= 0.041007978640038294
# differential_evolution step 442: f(x)= 0.041007978640038294
# differential_evolution step 443: f(x)= 0.041007978640038294
# differential_evolution step 444: f(x)= 0.041007978640038294
# differential_evolution step 445: f(x)= 0.041007978640038294
# differential_evolution step 446: f(x)= 0.041007978640038294
# differential_evolution step 447: f(x)= 0.041007978640038294
# differential_evolution step 448: f(x)= 0.041007978640038294
# differential_evolution step 449: f(x)= 0.041007978640038294
# differential_evolution step 450: f(x)= 0.041007978640038294
# differential_evolution step 451: f(x)= 0.041007978640038294
# differential_evolution step 452: f(x)= 0.041007978640038294
# differential_evolution step 453: f(x)= 0.041007978640038294
# differential_evolution step 454: f(x)= 0.041007978640038294
# differential_evolution step 455: f(x)= 0.041007978640038294
# differential_evolution step 456: f(x)= 0.041007978640038294
# differential_evolution step 457: f(x)= 0.041007978640038294
# differential_evolution step 458: f(x)= 0.04074812378759842
# differential_evolution step 459: f(x)= 0.04074812378759842
# differential_evolution step 460: f(x)= 0.04074812378759842
# differential_evolution step 461: f(x)= 0.04074812378759842
# differential_evolution step 462: f(x)= 0.04074812378759842
# differential_evolution step 463: f(x)= 0.04074812378759842
# differential_evolution step 464: f(x)= 0.04074812378759842
# differential_evolution step 465: f(x)= 0.04074812378759842
# differential_evolution step 466: f(x)= 0.04074812378759842
# differential_evolution step 467: f(x)= 0.04074812378759842
# differential_evolution step 468: f(x)= 0.04074812378759842
# differential_evolution step 469: f(x)= 0.04072771446920597
# differential_evolution step 470: f(x)= 0.04072771446920597
# differential_evolution step 471: f(x)= 0.04072771446920597
# differential_evolution step 472: f(x)= 0.04072771446920597
# differential_evolution step 473: f(x)= 0.04072771446920597
# differential_evolution step 474: f(x)= 0.04072771446920597
# differential_evolution step 475: f(x)= 0.04072771446920597
# differential_evolution step 476: f(x)= 0.04072771446920597
# differential_evolution step 477: f(x)= 0.04072771446920597
# differential_evolution step 478: f(x)= 0.04047554627500818
# differential_evolution step 479: f(x)= 0.04047554627500818
# differential_evolution step 480: f(x)= 0.04047554627500818
# differential_evolution step 481: f(x)= 0.04047554627500818
# differential_evolution step 482: f(x)= 0.04047554627500818
# differential_evolution step 483: f(x)= 0.04047554627500818
# differential_evolution step 484: f(x)= 0.04047554627500818
# differential_evolution step 485: f(x)= 0.04047554627500818
# differential_evolution step 486: f(x)= 0.04047554627500818
# differential_evolution step 487: f(x)= 0.04047554627500818
# differential_evolution step 488: f(x)= 0.04047554627500818
# differential_evolution step 489: f(x)= 0.04047554627500818
# differential_evolution step 490: f(x)= 0.04047554627500818
# differential_evolution step 491: f(x)= 0.04047554627500818
# differential_evolution step 492: f(x)= 0.04047554627500818
# differential_evolution step 493: f(x)= 0.04047554627500818
# differential_evolution step 494: f(x)= 0.04047554627500818
# differential_evolution step 495: f(x)= 0.04047554627500818
# differential_evolution step 496: f(x)= 0.04047554627500818
# differential_evolution step 497: f(x)= 0.04047554627500818
# differential_evolution step 498: f(x)= 0.04047554627500818
# differential_evolution step 499: f(x)= 0.04047554627500818
# differential_evolution step 500: f(x)= 0.04047554627500818
# differential_evolution step 501: f(x)= 0.04047554627500818
# differential_evolution step 502: f(x)= 0.04047554627500818
# differential_evolution step 503: f(x)= 0.04047554627500818
# differential_evolution step 504: f(x)= 0.04047554627500818
# differential_evolution step 505: f(x)= 0.04047554627500818
# differential_evolution step 506: f(x)= 0.04047554627500818
# differential_evolution step 507: f(x)= 0.04047554627500818
# differential_evolution step 508: f(x)= 0.04047554627500818
# differential_evolution step 509: f(x)= 0.04047554627500818
# differential_evolution step 510: f(x)= 0.04047554627500818
# differential_evolution step 511: f(x)= 0.04047554627500818
# differential_evolution step 512: f(x)= 0.04047554627500818
# differential_evolution step 513: f(x)= 0.04047554627500818
# differential_evolution step 514: f(x)= 0.04047554627500818
# differential_evolution step 515: f(x)= 0.04047554627500818
# differential_evolution step 516: f(x)= 0.04047554627500818
# differential_evolution step 517: f(x)= 0.04047554627500818
# differential_evolution step 518: f(x)= 0.04047554627500818
# differential_evolution step 519: f(x)= 0.04047554627500818
# differential_evolution step 520: f(x)= 0.04047554627500818
# differential_evolution step 521: f(x)= 0.04047554627500818
# differential_evolution step 522: f(x)= 0.04047554627500818
# differential_evolution step 523: f(x)= 0.04047554627500818
# differential_evolution step 524: f(x)= 0.04047554627500818
# differential_evolution step 525: f(x)= 0.04047554627500818
# differential_evolution step 526: f(x)= 0.04047554627500818
# differential_evolution step 527: f(x)= 0.03994725036069432
# differential_evolution step 528: f(x)= 0.03994725036069432
# differential_evolution step 529: f(x)= 0.03994725036069432
# differential_evolution step 530: f(x)= 0.03994725036069432
# differential_evolution step 531: f(x)= 0.03994725036069432
# differential_evolution step 532: f(x)= 0.03994725036069432
# differential_evolution step 533: f(x)= 0.03994725036069432
# differential_evolution step 534: f(x)= 0.03994725036069432
# differential_evolution step 535: f(x)= 0.03994725036069432
# differential_evolution step 536: f(x)= 0.03994725036069432
# differential_evolution step 537: f(x)= 0.03994725036069432
# differential_evolution step 538: f(x)= 0.03994725036069432
# differential_evolution step 539: f(x)= 0.03994725036069432
# differential_evolution step 540: f(x)= 0.03994725036069432
# differential_evolution step 541: f(x)= 0.03994725036069432
# differential_evolution step 542: f(x)= 0.03994725036069432
# differential_evolution step 543: f(x)= 0.03994725036069432
# differential_evolution step 544: f(x)= 0.03994725036069432
# differential_evolution step 545: f(x)= 0.03994725036069432
# differential_evolution step 546: f(x)= 0.03994725036069432
# differential_evolution step 547: f(x)= 0.03994725036069432
# differential_evolution step 548: f(x)= 0.03994725036069432
# differential_evolution step 549: f(x)= 0.03994725036069432
# differential_evolution step 550: f(x)= 0.03994725036069432
# differential_evolution step 551: f(x)= 0.03994725036069432
# differential_evolution step 552: f(x)= 0.03994725036069432
# differential_evolution step 553: f(x)= 0.03994725036069432
# differential_evolution step 554: f(x)= 0.03924425869474382
# differential_evolution step 555: f(x)= 0.03924425869474382
# differential_evolution step 556: f(x)= 0.03924425869474382
# differential_evolution step 557: f(x)= 0.03924425869474382
# differential_evolution step 558: f(x)= 0.03924425869474382
# differential_evolution step 559: f(x)= 0.03924425869474382
# differential_evolution step 560: f(x)= 0.03924425869474382
# differential_evolution step 561: f(x)= 0.03924425869474382
# differential_evolution step 562: f(x)= 0.03924425869474382
# differential_evolution step 563: f(x)= 0.03924425869474382
# differential_evolution step 564: f(x)= 0.03924425869474382
# differential_evolution step 565: f(x)= 0.03924425869474382
# differential_evolution step 566: f(x)= 0.03924425869474382
# differential_evolution step 567: f(x)= 0.03924425869474382
# differential_evolution step 568: f(x)= 0.03924425869474382
# differential_evolution step 569: f(x)= 0.03924425869474382
# differential_evolution step 570: f(x)= 0.03924425869474382
# differential_evolution step 571: f(x)= 0.03924425869474382
# differential_evolution step 572: f(x)= 0.03924425869474382
# differential_evolution step 573: f(x)= 0.03924425869474382
# differential_evolution step 574: f(x)= 0.03924425869474382
# differential_evolution step 575: f(x)= 0.03924425869474382
# differential_evolution step 576: f(x)= 0.03924425869474382
# differential_evolution step 577: f(x)= 0.03924425869474382
# differential_evolution step 578: f(x)= 0.03924425869474382
# differential_evolution step 579: f(x)= 0.03924425869474382
# differential_evolution step 580: f(x)= 0.03924425869474382
# differential_evolution step 581: f(x)= 0.03924425869474382
# differential_evolution step 582: f(x)= 0.03924425869474382
# differential_evolution step 583: f(x)= 0.03924425869474382
# differential_evolution step 584: f(x)= 0.03924425869474382
# differential_evolution step 585: f(x)= 0.03886395609455685
# differential_evolution step 586: f(x)= 0.03886395609455685
# differential_evolution step 587: f(x)= 0.03886395609455685
# differential_evolution step 588: f(x)= 0.03886395609455685
# differential_evolution step 589: f(x)= 0.03886395609455685
# differential_evolution step 590: f(x)= 0.03886395609455685
# differential_evolution step 591: f(x)= 0.03886395609455685
# differential_evolution step 592: f(x)= 0.03886395609455685
# differential_evolution step 593: f(x)= 0.03886395609455685
# differential_evolution step 594: f(x)= 0.03886395609455685
# differential_evolution step 595: f(x)= 0.03886395609455685
# differential_evolution step 596: f(x)= 0.03886395609455685
# differential_evolution step 597: f(x)= 0.03886395609455685
# differential_evolution step 598: f(x)= 0.03886395609455685
# differential_evolution step 599: f(x)= 0.03886395609455685
# differential_evolution step 600: f(x)= 0.03886395609455685
# differential_evolution step 601: f(x)= 0.03886395609455685
# differential_evolution step 602: f(x)= 0.03886395609455685
# differential_evolution step 603: f(x)= 0.03886395609455685
# differential_evolution step 604: f(x)= 0.03886395609455685
# differential_evolution step 605: f(x)= 0.03886395609455685
# differential_evolution step 606: f(x)= 0.03886395609455685
# differential_evolution step 607: f(x)= 0.03886395609455685
# differential_evolution step 608: f(x)= 0.03886395609455685
# differential_evolution step 609: f(x)= 0.03886395609455685
# differential_evolution step 610: f(x)= 0.03886395609455685
# differential_evolution step 611: f(x)= 0.03886395609455685
# differential_evolution step 612: f(x)= 0.03886395609455685
# differential_evolution step 613: f(x)= 0.03886395609455685
# differential_evolution step 614: f(x)= 0.03886395609455685
# differential_evolution step 615: f(x)= 0.03886395609455685
# differential_evolution step 616: f(x)= 0.03886395609455685
# differential_evolution step 617: f(x)= 0.03886395609455685
# differential_evolution step 618: f(x)= 0.03886395609455685
# differential_evolution step 619: f(x)= 0.03886395609455685
# differential_evolution step 620: f(x)= 0.03886395609455685
# differential_evolution step 621: f(x)= 0.03886395609455685
# differential_evolution step 622: f(x)= 0.03886395609455685
# differential_evolution step 623: f(x)= 0.03886395609455685
# differential_evolution step 624: f(x)= 0.03886395609455685
# differential_evolution step 625: f(x)= 0.03886395609455685
# differential_evolution step 626: f(x)= 0.03886395609455685
# differential_evolution step 627: f(x)= 0.03886395609455685
# differential_evolution step 628: f(x)= 0.03886395609455685
# differential_evolution step 629: f(x)= 0.03886395609455685
# differential_evolution step 630: f(x)= 0.03886395609455685
# differential_evolution step 631: f(x)= 0.03886395609455685
# differential_evolution step 632: f(x)= 0.03886395609455685
# differential_evolution step 633: f(x)= 0.03886395609455685
# differential_evolution step 634: f(x)= 0.03886395609455685
# differential_evolution step 635: f(x)= 0.03886395609455685
# differential_evolution step 636: f(x)= 0.03886395609455685
# differential_evolution step 637: f(x)= 0.03886395609455685
# differential_evolution step 638: f(x)= 0.03886395609455685
# differential_evolution step 639: f(x)= 0.03886395609455685
# differential_evolution step 640: f(x)= 0.03886395609455685
# differential_evolution step 641: f(x)= 0.03886395609455685
# differential_evolution step 642: f(x)= 0.03886395609455685
# differential_evolution step 643: f(x)= 0.03886395609455685
# differential_evolution step 644: f(x)= 0.03886395609455685
# differential_evolution step 645: f(x)= 0.03886395609455685
# differential_evolution step 646: f(x)= 0.03886395609455685
# differential_evolution step 647: f(x)= 0.03886395609455685
# differential_evolution step 648: f(x)= 0.03886395609455685
# differential_evolution step 649: f(x)= 0.03886395609455685
# differential_evolution step 650: f(x)= 0.03886395609455685
# differential_evolution step 651: f(x)= 0.03886395609455685
# differential_evolution step 652: f(x)= 0.03886395609455685
# differential_evolution step 653: f(x)= 0.03886395609455685
# differential_evolution step 654: f(x)= 0.03886395609455685
# differential_evolution step 655: f(x)= 0.03886395609455685
# differential_evolution step 656: f(x)= 0.03886395609455685
# differential_evolution step 657: f(x)= 0.03886395609455685
# differential_evolution step 658: f(x)= 0.03886395609455685
# differential_evolution step 659: f(x)= 0.03886395609455685
# differential_evolution step 660: f(x)= 0.03886395609455685
# differential_evolution step 661: f(x)= 0.03886395609455685
# differential_evolution step 662: f(x)= 0.03886395609455685
# differential_evolution step 663: f(x)= 0.03886395609455685
# differential_evolution step 664: f(x)= 0.03886395609455685
# differential_evolution step 665: f(x)= 0.03886395609455685
# differential_evolution step 666: f(x)= 0.03886395609455685
# differential_evolution step 667: f(x)= 0.03886395609455685
# differential_evolution step 668: f(x)= 0.03886395609455685
# differential_evolution step 669: f(x)= 0.03886395609455685
# differential_evolution step 670: f(x)= 0.03886395609455685
# differential_evolution step 671: f(x)= 0.03886395609455685
# differential_evolution step 672: f(x)= 0.03886395609455685
# differential_evolution step 673: f(x)= 0.03886395609455685
# differential_evolution step 674: f(x)= 0.03854484600104313
# differential_evolution step 675: f(x)= 0.03854484600104313
# differential_evolution step 676: f(x)= 0.03854484600104313
# differential_evolution step 677: f(x)= 0.03854484600104313
# differential_evolution step 678: f(x)= 0.03854484600104313
# differential_evolution step 679: f(x)= 0.03854484600104313
# differential_evolution step 680: f(x)= 0.03854484600104313
# differential_evolution step 681: f(x)= 0.03854484600104313
# differential_evolution step 682: f(x)= 0.03854484600104313
# differential_evolution step 683: f(x)= 0.03854484600104313
# differential_evolution step 684: f(x)= 0.03854484600104313
# differential_evolution step 685: f(x)= 0.03854484600104313
# differential_evolution step 686: f(x)= 0.03854484600104313
# differential_evolution step 687: f(x)= 0.03854484600104313
# differential_evolution step 688: f(x)= 0.03854484600104313
# differential_evolution step 689: f(x)= 0.03854484600104313
# differential_evolution step 690: f(x)= 0.03854484600104313
# differential_evolution step 691: f(x)= 0.03854484600104313
# differential_evolution step 692: f(x)= 0.03854484600104313
# differential_evolution step 693: f(x)= 0.03854484600104313
# differential_evolution step 694: f(x)= 0.03854484600104313
# differential_evolution step 695: f(x)= 0.03854484600104313
# differential_evolution step 696: f(x)= 0.03854484600104313
# differential_evolution step 697: f(x)= 0.03854484600104313
# differential_evolution step 698: f(x)= 0.03854484600104313
# differential_evolution step 699: f(x)= 0.03854484600104313
# differential_evolution step 700: f(x)= 0.03854484600104313
# differential_evolution step 701: f(x)= 0.03854484600104313
# differential_evolution step 702: f(x)= 0.03854484600104313
# differential_evolution step 703: f(x)= 0.03854484600104313
# differential_evolution step 704: f(x)= 0.03854484600104313
# differential_evolution step 705: f(x)= 0.03854484600104313
# differential_evolution step 706: f(x)= 0.03854484600104313
# differential_evolution step 707: f(x)= 0.03854484600104313
# differential_evolution step 708: f(x)= 0.03854484600104313
# differential_evolution step 709: f(x)= 0.03854484600104313
# differential_evolution step 710: f(x)= 0.03854484600104313
# differential_evolution step 711: f(x)= 0.03854484600104313
# differential_evolution step 712: f(x)= 0.03854484600104313
# differential_evolution step 713: f(x)= 0.03854484600104313
# differential_evolution step 714: f(x)= 0.03854484600104313
# differential_evolution step 715: f(x)= 0.03854484600104313
# differential_evolution step 716: f(x)= 0.03854484600104313
# differential_evolution step 717: f(x)= 0.03854484600104313
# differential_evolution step 718: f(x)= 0.03854484600104313
# differential_evolution step 719: f(x)= 0.03854484600104313
# differential_evolution step 720: f(x)= 0.03854484600104313
# differential_evolution step 721: f(x)= 0.03854484600104313
# differential_evolution step 722: f(x)= 0.03854484600104313
# differential_evolution step 723: f(x)= 0.03854484600104313
# differential_evolution step 724: f(x)= 0.03854484600104313
# differential_evolution step 725: f(x)= 0.03854484600104313
# differential_evolution step 726: f(x)= 0.03854484600104313
# differential_evolution step 727: f(x)= 0.03854484600104313
# differential_evolution step 728: f(x)= 0.03854484600104313
# differential_evolution step 729: f(x)= 0.03854484600104313
# differential_evolution step 730: f(x)= 0.03854484600104313
# differential_evolution step 731: f(x)= 0.03854484600104313
# differential_evolution step 732: f(x)= 0.03854484600104313
# differential_evolution step 733: f(x)= 0.038536675150950744
# differential_evolution step 734: f(x)= 0.038536675150950744
# differential_evolution step 735: f(x)= 0.038536675150950744
# differential_evolution step 736: f(x)= 0.038536675150950744
# differential_evolution step 737: f(x)= 0.038536675150950744
# differential_evolution step 738: f(x)= 0.038536675150950744
# differential_evolution step 739: f(x)= 0.038536675150950744
# differential_evolution step 740: f(x)= 0.038536675150950744
# differential_evolution step 741: f(x)= 0.038536675150950744
# differential_evolution step 742: f(x)= 0.038536675150950744
# differential_evolution step 743: f(x)= 0.038536675150950744
# differential_evolution step 744: f(x)= 0.038536675150950744
# differential_evolution step 745: f(x)= 0.038536675150950744
# differential_evolution step 746: f(x)= 0.038536675150950744
# differential_evolution step 747: f(x)= 0.038536675150950744
# differential_evolution step 748: f(x)= 0.038536675150950744
# differential_evolution step 749: f(x)= 0.038536675150950744
# differential_evolution step 750: f(x)= 0.038536675150950744
# differential_evolution step 751: f(x)= 0.038536675150950744
# differential_evolution step 752: f(x)= 0.038536675150950744
# differential_evolution step 753: f(x)= 0.038474140300557624
# differential_evolution step 754: f(x)= 0.038474140300557624
# differential_evolution step 755: f(x)= 0.038474140300557624
# differential_evolution step 756: f(x)= 0.038474140300557624
# differential_evolution step 757: f(x)= 0.038474140300557624
# differential_evolution step 758: f(x)= 0.038474140300557624
# differential_evolution step 759: f(x)= 0.038474140300557624
# differential_evolution step 760: f(x)= 0.038474140300557624
# differential_evolution step 761: f(x)= 0.038474140300557624
# differential_evolution step 762: f(x)= 0.038474140300557624
# differential_evolution step 763: f(x)= 0.038474140300557624
# differential_evolution step 764: f(x)= 0.038474140300557624
# differential_evolution step 765: f(x)= 0.038474140300557624
# differential_evolution step 766: f(x)= 0.038474140300557624
# differential_evolution step 767: f(x)= 0.038474140300557624
# differential_evolution step 768: f(x)= 0.038474140300557624
# differential_evolution step 769: f(x)= 0.038474140300557624
# differential_evolution step 770: f(x)= 0.038474140300557624
# differential_evolution step 771: f(x)= 0.038474140300557624
# differential_evolution step 772: f(x)= 0.038474140300557624
# differential_evolution step 773: f(x)= 0.038474140300557624
# differential_evolution step 774: f(x)= 0.038474140300557624
# differential_evolution step 775: f(x)= 0.038474140300557624
# differential_evolution step 776: f(x)= 0.038474140300557624
# differential_evolution step 777: f(x)= 0.038474140300557624
# differential_evolution step 778: f(x)= 0.038474140300557624
# differential_evolution step 779: f(x)= 0.03824721394437486
# differential_evolution step 780: f(x)= 0.03824721394437486
# differential_evolution step 781: f(x)= 0.03824721394437486
# differential_evolution step 782: f(x)= 0.03824721394437486
# differential_evolution step 783: f(x)= 0.03824721394437486
# differential_evolution step 784: f(x)= 0.03824721394437486
# differential_evolution step 785: f(x)= 0.038210224440205845
# differential_evolution step 786: f(x)= 0.038210224440205845
# differential_evolution step 787: f(x)= 0.038210224440205845
# differential_evolution step 788: f(x)= 0.038210224440205845
# differential_evolution step 789: f(x)= 0.038210224440205845
# differential_evolution step 790: f(x)= 0.038210224440205845
# differential_evolution step 791: f(x)= 0.038210224440205845
# differential_evolution step 792: f(x)= 0.038210224440205845
# differential_evolution step 793: f(x)= 0.03760330184204914
# differential_evolution step 794: f(x)= 0.03760330184204914
# differential_evolution step 795: f(x)= 0.03760330184204914
# differential_evolution step 796: f(x)= 0.03760330184204914
# differential_evolution step 797: f(x)= 0.03760330184204914
# differential_evolution step 798: f(x)= 0.03760330184204914
# differential_evolution step 799: f(x)= 0.03760330184204914
# differential_evolution step 800: f(x)= 0.03760330184204914
# differential_evolution step 801: f(x)= 0.03760330184204914
# differential_evolution step 802: f(x)= 0.03760330184204914
# differential_evolution step 803: f(x)= 0.03760330184204914
# differential_evolution step 804: f(x)= 0.03760330184204914
# differential_evolution step 805: f(x)= 0.03760330184204914
# differential_evolution step 806: f(x)= 0.03760330184204914
# differential_evolution step 807: f(x)= 0.03760330184204914
# differential_evolution step 808: f(x)= 0.03760330184204914
# differential_evolution step 809: f(x)= 0.03760330184204914
# differential_evolution step 810: f(x)= 0.03760330184204914
# differential_evolution step 811: f(x)= 0.03760330184204914
# differential_evolution step 812: f(x)= 0.03760330184204914
# differential_evolution step 813: f(x)= 0.03760330184204914
# differential_evolution step 814: f(x)= 0.03760330184204914
# differential_evolution step 815: f(x)= 0.03760330184204914
# differential_evolution step 816: f(x)= 0.03760330184204914
# differential_evolution step 817: f(x)= 0.03760330184204914
# differential_evolution step 818: f(x)= 0.03760330184204914
# differential_evolution step 819: f(x)= 0.03760330184204914
# differential_evolution step 820: f(x)= 0.03760330184204914
# differential_evolution step 821: f(x)= 0.03760330184204914
# differential_evolution step 822: f(x)= 0.03760330184204914
# differential_evolution step 823: f(x)= 0.03760330184204914
# differential_evolution step 824: f(x)= 0.03760330184204914
# differential_evolution step 825: f(x)= 0.03760330184204914
# differential_evolution step 826: f(x)= 0.03760330184204914
# differential_evolution step 827: f(x)= 0.03760330184204914
# differential_evolution step 828: f(x)= 0.03760330184204914
# differential_evolution step 829: f(x)= 0.03760330184204914
# differential_evolution step 830: f(x)= 0.03760330184204914
# differential_evolution step 831: f(x)= 0.03760330184204914
# differential_evolution step 832: f(x)= 0.03760330184204914
# differential_evolution step 833: f(x)= 0.03760330184204914
# differential_evolution step 834: f(x)= 0.03760330184204914
# differential_evolution step 835: f(x)= 0.03760330184204914
# differential_evolution step 836: f(x)= 0.03760330184204914
# differential_evolution step 837: f(x)= 0.03760330184204914
# differential_evolution step 838: f(x)= 0.03746952826040445
# differential_evolution step 839: f(x)= 0.03746952826040445
# differential_evolution step 840: f(x)= 0.03746952826040445
# differential_evolution step 841: f(x)= 0.03746952826040445
# differential_evolution step 842: f(x)= 0.03746952826040445
# differential_evolution step 843: f(x)= 0.03746952826040445
# differential_evolution step 844: f(x)= 0.03746952826040445
# differential_evolution step 845: f(x)= 0.03746952826040445
# differential_evolution step 846: f(x)= 0.03746952826040445
# differential_evolution step 847: f(x)= 0.03746952826040445
# differential_evolution step 848: f(x)= 0.03746952826040445
# differential_evolution step 849: f(x)= 0.03746952826040445
# differential_evolution step 850: f(x)= 0.037337823105799035
# differential_evolution step 851: f(x)= 0.037337823105799035
# differential_evolution step 852: f(x)= 0.037337823105799035
# differential_evolution step 853: f(x)= 0.037337823105799035
# differential_evolution step 854: f(x)= 0.037337823105799035
# differential_evolution step 855: f(x)= 0.037337823105799035
# differential_evolution step 856: f(x)= 0.037337823105799035
# differential_evolution step 857: f(x)= 0.037337823105799035
# differential_evolution step 858: f(x)= 0.037337823105799035
# differential_evolution step 859: f(x)= 0.037337823105799035
# differential_evolution step 860: f(x)= 0.037337823105799035
# differential_evolution step 861: f(x)= 0.037337823105799035
# differential_evolution step 862: f(x)= 0.037337823105799035
# differential_evolution step 863: f(x)= 0.037337823105799035
# differential_evolution step 864: f(x)= 0.037337823105799035
# differential_evolution step 865: f(x)= 0.037337823105799035
# differential_evolution step 866: f(x)= 0.037337823105799035
# differential_evolution step 867: f(x)= 0.037337823105799035
# differential_evolution step 868: f(x)= 0.037337823105799035
# differential_evolution step 869: f(x)= 0.037337823105799035
# differential_evolution step 870: f(x)= 0.037337823105799035
# differential_evolution step 871: f(x)= 0.03716165463673804
# differential_evolution step 872: f(x)= 0.03716165463673804
# differential_evolution step 873: f(x)= 0.03716165463673804
# differential_evolution step 874: f(x)= 0.03716165463673804
# differential_evolution step 875: f(x)= 0.03716165463673804
# differential_evolution step 876: f(x)= 0.03716165463673804
# differential_evolution step 877: f(x)= 0.03716165463673804
# differential_evolution step 878: f(x)= 0.03716165463673804
# differential_evolution step 879: f(x)= 0.03716165463673804
# differential_evolution step 880: f(x)= 0.03716165463673804
# differential_evolution step 881: f(x)= 0.03716165463673804
# differential_evolution step 882: f(x)= 0.03716165463673804
# differential_evolution step 883: f(x)= 0.03716165463673804
# differential_evolution step 884: f(x)= 0.03716165463673804
# differential_evolution step 885: f(x)= 0.03716165463673804
# differential_evolution step 886: f(x)= 0.03716165463673804
# differential_evolution step 887: f(x)= 0.03716165463673804
# differential_evolution step 888: f(x)= 0.03716165463673804
# differential_evolution step 889: f(x)= 0.03716165463673804
# differential_evolution step 890: f(x)= 0.03716165463673804
# differential_evolution step 891: f(x)= 0.03716165463673804
# differential_evolution step 892: f(x)= 0.03716165463673804
# differential_evolution step 893: f(x)= 0.03716165463673804
# differential_evolution step 894: f(x)= 0.03716165463673804
# differential_evolution step 895: f(x)= 0.03716165463673804
# differential_evolution step 896: f(x)= 0.03716165463673804
# differential_evolution step 897: f(x)= 0.03716165463673804
# differential_evolution step 898: f(x)= 0.03716165463673804
# differential_evolution step 899: f(x)= 0.03716165463673804
# differential_evolution step 900: f(x)= 0.03716165463673804
# differential_evolution step 901: f(x)= 0.03716165463673804
# differential_evolution step 902: f(x)= 0.03716165463673804
# differential_evolution step 903: f(x)= 0.03716165463673804
# differential_evolution step 904: f(x)= 0.03716165463673804
# differential_evolution step 905: f(x)= 0.03716165463673804
# differential_evolution step 906: f(x)= 0.03716165463673804
# differential_evolution step 907: f(x)= 0.03716165463673804
# differential_evolution step 908: f(x)= 0.03716165463673804
# differential_evolution step 909: f(x)= 0.03716165463673804
# differential_evolution step 910: f(x)= 0.03716165463673804
# differential_evolution step 911: f(x)= 0.03716165463673804
# differential_evolution step 912: f(x)= 0.03716165463673804
# differential_evolution step 913: f(x)= 0.03716165463673804
# differential_evolution step 914: f(x)= 0.03716165463673804
# differential_evolution step 915: f(x)= 0.03716165463673804
# differential_evolution step 916: f(x)= 0.03716165463673804
# differential_evolution step 917: f(x)= 0.03716165463673804
# differential_evolution step 918: f(x)= 0.03716165463673804
# differential_evolution step 919: f(x)= 0.03716165463673804
# differential_evolution step 920: f(x)= 0.03716165463673804
# differential_evolution step 921: f(x)= 0.03716165463673804
# differential_evolution step 922: f(x)= 0.03716165463673804
# differential_evolution step 923: f(x)= 0.03716165463673804
# differential_evolution step 924: f(x)= 0.03716165463673804
# differential_evolution step 925: f(x)= 0.03716165463673804
# differential_evolution step 926: f(x)= 0.03716165463673804
# differential_evolution step 927: f(x)= 0.03716165463673804
# differential_evolution step 928: f(x)= 0.03716165463673804
# differential_evolution step 929: f(x)= 0.03716165463673804
# differential_evolution step 930: f(x)= 0.03716165463673804
# differential_evolution step 931: f(x)= 0.03716165463673804
# differential_evolution step 932: f(x)= 0.03716165463673804
# differential_evolution step 933: f(x)= 0.03716165463673804
# differential_evolution step 934: f(x)= 0.03716165463673804
# differential_evolution step 935: f(x)= 0.03716165463673804
# differential_evolution step 936: f(x)= 0.03716165463673804
# differential_evolution step 937: f(x)= 0.03716165463673804
# differential_evolution step 938: f(x)= 0.03716165463673804
# differential_evolution step 939: f(x)= 0.03716165463673804
# differential_evolution step 940: f(x)= 0.03716165463673804
# differential_evolution step 941: f(x)= 0.03716165463673804
# differential_evolution step 942: f(x)= 0.03716165463673804
# differential_evolution step 943: f(x)= 0.03716165463673804
# differential_evolution step 944: f(x)= 0.03716165463673804
# differential_evolution step 945: f(x)= 0.03716165463673804
# differential_evolution step 946: f(x)= 0.03716165463673804
# differential_evolution step 947: f(x)= 0.03716165463673804
# differential_evolution step 948: f(x)= 0.03716165463673804
# differential_evolution step 949: f(x)= 0.03716165463673804
# differential_evolution step 950: f(x)= 0.03711581066286045
# differential_evolution step 951: f(x)= 0.03711581066286045
# differential_evolution step 952: f(x)= 0.03711581066286045
# differential_evolution step 953: f(x)= 0.03711581066286045
# differential_evolution step 954: f(x)= 0.03711581066286045
# differential_evolution step 955: f(x)= 0.03711581066286045
# differential_evolution step 956: f(x)= 0.03711581066286045
# differential_evolution step 957: f(x)= 0.03711581066286045
# differential_evolution step 958: f(x)= 0.03711581066286045
# differential_evolution step 959: f(x)= 0.03711581066286045
# differential_evolution step 960: f(x)= 0.03711581066286045
# differential_evolution step 961: f(x)= 0.03711581066286045
# differential_evolution step 962: f(x)= 0.03711581066286045
# differential_evolution step 963: f(x)= 0.03711581066286045
# differential_evolution step 964: f(x)= 0.03711581066286045
# differential_evolution step 965: f(x)= 0.03711581066286045
# differential_evolution step 966: f(x)= 0.03711581066286045
# differential_evolution step 967: f(x)= 0.03711581066286045
# differential_evolution step 968: f(x)= 0.03711581066286045
# differential_evolution step 969: f(x)= 0.03711581066286045
# differential_evolution step 970: f(x)= 0.03711581066286045
# differential_evolution step 971: f(x)= 0.03711581066286045
# differential_evolution step 972: f(x)= 0.03711581066286045
# differential_evolution step 973: f(x)= 0.03711581066286045
# differential_evolution step 974: f(x)= 0.03711581066286045
# differential_evolution step 975: f(x)= 0.03711581066286045
# differential_evolution step 976: f(x)= 0.03711581066286045
# differential_evolution step 977: f(x)= 0.03711581066286045
# differential_evolution step 978: f(x)= 0.03711581066286045
# differential_evolution step 979: f(x)= 0.03711581066286045
# differential_evolution step 980: f(x)= 0.03711581066286045
# differential_evolution step 981: f(x)= 0.03711581066286045
# differential_evolution step 982: f(x)= 0.03711581066286045
# differential_evolution step 983: f(x)= 0.03711581066286045
# differential_evolution step 984: f(x)= 0.03711581066286045
# differential_evolution step 985: f(x)= 0.03711581066286045
# differential_evolution step 986: f(x)= 0.03711581066286045
# differential_evolution step 987: f(x)= 0.03711581066286045
# differential_evolution step 988: f(x)= 0.03711581066286045
# differential_evolution step 989: f(x)= 0.03711581066286045
# differential_evolution step 990: f(x)= 0.03711581066286045
# differential_evolution step 991: f(x)= 0.03711581066286045
# differential_evolution step 992: f(x)= 0.03711581066286045
# differential_evolution step 993: f(x)= 0.03711581066286045
# differential_evolution step 994: f(x)= 0.03711581066286045
# differential_evolution step 995: f(x)= 0.03711581066286045
# differential_evolution step 996: f(x)= 0.03711581066286045
# differential_evolution step 997: f(x)= 0.03711581066286045
# differential_evolution step 998: f(x)= 0.03711581066286045
# differential_evolution step 999: f(x)= 0.03711581066286045
# differential_evolution step 1000: f(x)= 0.03711581066286045
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_19220\3550005930.py:11: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.0429, r_e=0.0240, n=3.2745, x_0=27.4411
# Sérsic 2: I_e=0.1473, r_e=20.0000, n=0.2684, x_0=45.4205
# Sérsic 3: I_e=3.0896, r_e=0.0221, n=2.8822, x_0=61.3603
# Sérsic 4: I_e=0.0292, r_e=3.5499, n=1.0115, x_0=69.1112
# Sérsic 5: I_e=0.0352, r_e=19.7346, n=0.4017, x_0=100.3360
# Chi quadro minimo: 0.03574586923090002
# False

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=2.0429, r_e=0.0240, n=3.2745, x_0=27.4411
# Sérsic 2: I_e=0.1473, r_e=20.0000, n=0.2684, x_0=45.4205
# Sérsic 3: I_e=3.0896, r_e=0.0221, n=2.8822, x_0=61.3603
# Sérsic 4: I_e=0.0292, r_e=3.5499, n=1.0115, x_0=69.1112
# Sérsic 5: I_e=0.0352, r_e=19.7346, n=0.4017, x_0=100.3360
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = real_errors_SII, bounds = bounds_list)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.4034, r_e=0.0493, n=3.7732, x_0=27.4477
# Sérsic 2: I_e=0.1438, r_e=20.0000, n=0.2650, x_0=45.4205
# Sérsic 3: I_e=3.0893, r_e=0.0039, n=2.8817, x_0=61.3599
# Sérsic 4: I_e=0.0061, r_e=19.0727, n=1.8462, x_0=68.6207
# Sérsic 5: I_e=0.0270, r_e=19.9962, n=0.5467, x_0=100.2260
# [9.86433746e+03 3.53267845e+02 4.46731306e+04 1.37069030e+01
#  1.77896651e-02 1.74760541e+00 8.43495219e-02 3.39087810e+00
#  1.98151719e+06 2.04057842e+03 1.40154651e+06 1.10196991e+02
#  6.90666173e-02 1.65044933e+02 9.21742243e+00 1.21199531e+00
#  2.82191143e-02 2.99284513e+01 6.89713471e-01 6.21477048e+00]
# 0.3256545440176521

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))
real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[2])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_OIII
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 21312.608959628807
# differential_evolution step 2: f(x)= 21312.608959628807
# differential_evolution step 3: f(x)= 21312.608959628807
# differential_evolution step 4: f(x)= 21312.608959628807
# differential_evolution step 5: f(x)= 8313.54606824889
# differential_evolution step 6: f(x)= 8313.54606824889
# differential_evolution step 7: f(x)= 2511.258744002227
# differential_evolution step 8: f(x)= 2080.095233672389
# differential_evolution step 9: f(x)= 2080.095233672389
# differential_evolution step 10: f(x)= 2080.095233672389
# differential_evolution step 11: f(x)= 2080.095233672389
# differential_evolution step 12: f(x)= 992.2855358795123
# differential_evolution step 13: f(x)= 992.2855358795123
# differential_evolution step 14: f(x)= 992.2855358795123
# differential_evolution step 15: f(x)= 992.2855358795123
# differential_evolution step 16: f(x)= 369.21233765462136
# differential_evolution step 17: f(x)= 369.21233765462136
# differential_evolution step 18: f(x)= 369.21233765462136
# differential_evolution step 19: f(x)= 369.21233765462136
# differential_evolution step 20: f(x)= 369.21233765462136
# differential_evolution step 21: f(x)= 369.21233765462136
# differential_evolution step 22: f(x)= 369.21233765462136
# differential_evolution step 23: f(x)= 369.21233765462136
# differential_evolution step 24: f(x)= 194.96657402641918
# differential_evolution step 25: f(x)= 194.96657402641918
# differential_evolution step 26: f(x)= 194.96657402641918
# differential_evolution step 27: f(x)= 179.0925373271188
# differential_evolution step 28: f(x)= 179.0925373271188
# differential_evolution step 29: f(x)= 179.0925373271188
# differential_evolution step 30: f(x)= 179.0925373271188
# differential_evolution step 31: f(x)= 179.0925373271188
# differential_evolution step 32: f(x)= 17.764767072848706
# differential_evolution step 33: f(x)= 17.764767072848706
# differential_evolution step 34: f(x)= 17.764767072848706
# differential_evolution step 35: f(x)= 17.764767072848706
# differential_evolution step 36: f(x)= 17.764767072848706
# differential_evolution step 37: f(x)= 17.764767072848706
# differential_evolution step 38: f(x)= 17.764767072848706
# differential_evolution step 39: f(x)= 17.764767072848706
# differential_evolution step 40: f(x)= 17.764767072848706
# differential_evolution step 41: f(x)= 12.384717250335738
# differential_evolution step 42: f(x)= 12.384717250335738
# differential_evolution step 43: f(x)= 12.384717250335738
# differential_evolution step 44: f(x)= 12.384717250335738
# differential_evolution step 45: f(x)= 12.384717250335738
# differential_evolution step 46: f(x)= 12.384717250335738
# differential_evolution step 47: f(x)= 12.384717250335738
# differential_evolution step 48: f(x)= 12.384717250335738
# differential_evolution step 49: f(x)= 12.384717250335738
# differential_evolution step 50: f(x)= 12.384717250335738
# differential_evolution step 51: f(x)= 12.384717250335738
# differential_evolution step 52: f(x)= 12.384717250335738
# differential_evolution step 53: f(x)= 12.384717250335738
# differential_evolution step 54: f(x)= 12.384717250335738
# differential_evolution step 55: f(x)= 12.384717250335738
# differential_evolution step 56: f(x)= 12.384717250335738
# differential_evolution step 57: f(x)= 7.744673227224073
# differential_evolution step 58: f(x)= 6.265622107701736
# differential_evolution step 59: f(x)= 6.265622107701736
# differential_evolution step 60: f(x)= 6.265622107701736
# differential_evolution step 61: f(x)= 6.265622107701736
# differential_evolution step 62: f(x)= 6.265622107701736
# differential_evolution step 63: f(x)= 6.265622107701736
# differential_evolution step 64: f(x)= 6.265622107701736
# differential_evolution step 65: f(x)= 6.265622107701736
# differential_evolution step 66: f(x)= 6.265622107701736
# differential_evolution step 67: f(x)= 6.265622107701736
# differential_evolution step 68: f(x)= 6.265622107701736
# differential_evolution step 69: f(x)= 6.265622107701736
# differential_evolution step 70: f(x)= 6.265622107701736
# differential_evolution step 71: f(x)= 6.265622107701736
# differential_evolution step 72: f(x)= 6.265622107701736
# differential_evolution step 73: f(x)= 6.265622107701736
# differential_evolution step 74: f(x)= 6.265622107701736
# differential_evolution step 75: f(x)= 6.265622107701736
# differential_evolution step 76: f(x)= 6.265622107701736
# differential_evolution step 77: f(x)= 6.265622107701736
# differential_evolution step 78: f(x)= 6.265622107701736
# differential_evolution step 79: f(x)= 5.2777803673089
# differential_evolution step 80: f(x)= 5.2777803673089
# differential_evolution step 81: f(x)= 5.265928681273262
# differential_evolution step 82: f(x)= 5.265928681273262
# differential_evolution step 83: f(x)= 5.265928681273262
# differential_evolution step 84: f(x)= 5.265928681273262
# differential_evolution step 85: f(x)= 5.265928681273262
# differential_evolution step 86: f(x)= 5.265928681273262
# differential_evolution step 87: f(x)= 5.265928681273262
# differential_evolution step 88: f(x)= 5.265928681273262
# differential_evolution step 89: f(x)= 5.265928681273262
# differential_evolution step 90: f(x)= 5.265928681273262
# differential_evolution step 91: f(x)= 5.265928681273262
# differential_evolution step 92: f(x)= 5.265928681273262
# differential_evolution step 93: f(x)= 3.956312589358567
# differential_evolution step 94: f(x)= 3.4506771044112
# differential_evolution step 95: f(x)= 3.4506771044112
# differential_evolution step 96: f(x)= 2.8739538637821003
# differential_evolution step 97: f(x)= 2.8739538637821003
# differential_evolution step 98: f(x)= 2.8739538637821003
# differential_evolution step 99: f(x)= 1.6860081847565382
# differential_evolution step 100: f(x)= 1.6860081847565382
# differential_evolution step 101: f(x)= 1.6860081847565382
# differential_evolution step 102: f(x)= 1.6860081847565382
# differential_evolution step 103: f(x)= 1.6860081847565382
# differential_evolution step 104: f(x)= 1.6860081847565382
# differential_evolution step 105: f(x)= 1.6860081847565382
# differential_evolution step 106: f(x)= 1.6860081847565382
# differential_evolution step 107: f(x)= 1.6860081847565382
# differential_evolution step 108: f(x)= 1.6860081847565382
# differential_evolution step 109: f(x)= 1.0652127666072693
# differential_evolution step 110: f(x)= 1.0652127666072693
# differential_evolution step 111: f(x)= 1.0652127666072693
# differential_evolution step 112: f(x)= 1.0652127666072693
# differential_evolution step 113: f(x)= 1.0652127666072693
# differential_evolution step 114: f(x)= 1.0652127666072693
# differential_evolution step 115: f(x)= 1.0652127666072693
# differential_evolution step 116: f(x)= 1.0652127666072693
# differential_evolution step 117: f(x)= 1.0652127666072693
# differential_evolution step 118: f(x)= 1.0652127666072693
# differential_evolution step 119: f(x)= 1.0652127666072693
# differential_evolution step 120: f(x)= 1.0652127666072693
# differential_evolution step 121: f(x)= 1.0652127666072693
# differential_evolution step 122: f(x)= 1.0652127666072693
# differential_evolution step 123: f(x)= 1.0652127666072693
# differential_evolution step 124: f(x)= 1.0652127666072693
# differential_evolution step 125: f(x)= 1.0652127666072693
# differential_evolution step 126: f(x)= 1.0652127666072693
# differential_evolution step 127: f(x)= 1.0652127666072693
# differential_evolution step 128: f(x)= 1.0652127666072693
# differential_evolution step 129: f(x)= 1.0652127666072693
# differential_evolution step 130: f(x)= 1.0652127666072693
# differential_evolution step 131: f(x)= 1.0652127666072693
# differential_evolution step 132: f(x)= 1.0652127666072693
# differential_evolution step 133: f(x)= 1.0652127666072693
# differential_evolution step 134: f(x)= 1.0652127666072693
# differential_evolution step 135: f(x)= 1.0652127666072693
# differential_evolution step 136: f(x)= 1.0652127666072693
# differential_evolution step 137: f(x)= 1.0652127666072693
# differential_evolution step 138: f(x)= 1.0652127666072693
# differential_evolution step 139: f(x)= 1.0652127666072693
# differential_evolution step 140: f(x)= 1.0652127666072693
# differential_evolution step 141: f(x)= 1.0652127666072693
# differential_evolution step 142: f(x)= 1.0652127666072693
# differential_evolution step 143: f(x)= 1.0652127666072693
# differential_evolution step 144: f(x)= 1.0652127666072693
# differential_evolution step 145: f(x)= 1.0652127666072693
# differential_evolution step 146: f(x)= 1.0652127666072693
# differential_evolution step 147: f(x)= 1.0003572525189863
# differential_evolution step 148: f(x)= 1.0003572525189863
# differential_evolution step 149: f(x)= 1.0003572525189863
# differential_evolution step 150: f(x)= 0.7530997218783773
# differential_evolution step 151: f(x)= 0.438494206936195
# differential_evolution step 152: f(x)= 0.438494206936195
# differential_evolution step 153: f(x)= 0.438494206936195
# differential_evolution step 154: f(x)= 0.438494206936195
# differential_evolution step 155: f(x)= 0.438494206936195
# differential_evolution step 156: f(x)= 0.438494206936195
# differential_evolution step 157: f(x)= 0.438494206936195
# differential_evolution step 158: f(x)= 0.438494206936195
# differential_evolution step 159: f(x)= 0.438494206936195
# differential_evolution step 160: f(x)= 0.438494206936195
# differential_evolution step 161: f(x)= 0.438494206936195
# differential_evolution step 162: f(x)= 0.438494206936195
# differential_evolution step 163: f(x)= 0.438494206936195
# differential_evolution step 164: f(x)= 0.438494206936195
# differential_evolution step 165: f(x)= 0.438494206936195
# differential_evolution step 166: f(x)= 0.438494206936195
# differential_evolution step 167: f(x)= 0.438494206936195
# differential_evolution step 168: f(x)= 0.438494206936195
# differential_evolution step 169: f(x)= 0.438494206936195
# differential_evolution step 170: f(x)= 0.438494206936195
# differential_evolution step 171: f(x)= 0.438494206936195
# differential_evolution step 172: f(x)= 0.438494206936195
# differential_evolution step 173: f(x)= 0.438494206936195
# differential_evolution step 174: f(x)= 0.438494206936195
# differential_evolution step 175: f(x)= 0.438494206936195
# differential_evolution step 176: f(x)= 0.438494206936195
# differential_evolution step 177: f(x)= 0.438494206936195
# differential_evolution step 178: f(x)= 0.438494206936195
# differential_evolution step 179: f(x)= 0.4255185504991604
# differential_evolution step 180: f(x)= 0.4255185504991604
# differential_evolution step 181: f(x)= 0.4255185504991604
# differential_evolution step 182: f(x)= 0.4255185504991604
# differential_evolution step 183: f(x)= 0.4255185504991604
# differential_evolution step 184: f(x)= 0.4255185504991604
# differential_evolution step 185: f(x)= 0.4255185504991604
# differential_evolution step 186: f(x)= 0.4255185504991604
# differential_evolution step 187: f(x)= 0.4255185504991604
# differential_evolution step 188: f(x)= 0.4255185504991604
# differential_evolution step 189: f(x)= 0.4255185504991604
# differential_evolution step 190: f(x)= 0.4255185504991604
# differential_evolution step 191: f(x)= 0.4255185504991604
# differential_evolution step 192: f(x)= 0.4255185504991604
# differential_evolution step 193: f(x)= 0.4255185504991604
# differential_evolution step 194: f(x)= 0.4255185504991604
# differential_evolution step 195: f(x)= 0.4255185504991604
# differential_evolution step 196: f(x)= 0.4255185504991604
# differential_evolution step 197: f(x)= 0.4255185504991604
# differential_evolution step 198: f(x)= 0.4255185504991604
# differential_evolution step 199: f(x)= 0.4144726338017763
# differential_evolution step 200: f(x)= 0.3964197847108301
# differential_evolution step 201: f(x)= 0.3964197847108301
# differential_evolution step 202: f(x)= 0.31055303334427753
# differential_evolution step 203: f(x)= 0.31055303334427753
# differential_evolution step 204: f(x)= 0.31055303334427753
# differential_evolution step 205: f(x)= 0.31055303334427753
# differential_evolution step 206: f(x)= 0.31055303334427753
# differential_evolution step 207: f(x)= 0.31055303334427753
# differential_evolution step 208: f(x)= 0.27725743779526774
# differential_evolution step 209: f(x)= 0.27725743779526774
# differential_evolution step 210: f(x)= 0.27725743779526774
# differential_evolution step 211: f(x)= 0.27725743779526774
# differential_evolution step 212: f(x)= 0.2757093965635341
# differential_evolution step 213: f(x)= 0.2757093965635341
# differential_evolution step 214: f(x)= 0.2757093965635341
# differential_evolution step 215: f(x)= 0.2757093965635341
# differential_evolution step 216: f(x)= 0.2757093965635341
# differential_evolution step 217: f(x)= 0.2757093965635341
# differential_evolution step 218: f(x)= 0.2757093965635341
# differential_evolution step 219: f(x)= 0.2757093965635341
# differential_evolution step 220: f(x)= 0.2757093965635341
# differential_evolution step 221: f(x)= 0.2757093965635341
# differential_evolution step 222: f(x)= 0.2757093965635341
# differential_evolution step 223: f(x)= 0.2757093965635341
# differential_evolution step 224: f(x)= 0.25928562287726475
# differential_evolution step 225: f(x)= 0.25928562287726475
# differential_evolution step 226: f(x)= 0.25928562287726475
# differential_evolution step 227: f(x)= 0.25928562287726475
# differential_evolution step 228: f(x)= 0.25928562287726475
# differential_evolution step 229: f(x)= 0.25928562287726475
# differential_evolution step 230: f(x)= 0.25928562287726475
# differential_evolution step 231: f(x)= 0.22964925069514236
# differential_evolution step 232: f(x)= 0.22964925069514236
# differential_evolution step 233: f(x)= 0.22964925069514236
# differential_evolution step 234: f(x)= 0.22964925069514236
# differential_evolution step 235: f(x)= 0.22964925069514236
# differential_evolution step 236: f(x)= 0.22964925069514236
# differential_evolution step 237: f(x)= 0.22964925069514236
# differential_evolution step 238: f(x)= 0.22964925069514236
# differential_evolution step 239: f(x)= 0.22964925069514236
# differential_evolution step 240: f(x)= 0.22964925069514236
# differential_evolution step 241: f(x)= 0.22964925069514236
# differential_evolution step 242: f(x)= 0.22964925069514236
# differential_evolution step 243: f(x)= 0.22964925069514236
# differential_evolution step 244: f(x)= 0.22964925069514236
# differential_evolution step 245: f(x)= 0.22964925069514236
# differential_evolution step 246: f(x)= 0.22964925069514236
# differential_evolution step 247: f(x)= 0.22964925069514236
# differential_evolution step 248: f(x)= 0.22447038701764135
# differential_evolution step 249: f(x)= 0.22447038701764135
# differential_evolution step 250: f(x)= 0.2218596816503148
# differential_evolution step 251: f(x)= 0.2218596816503148
# differential_evolution step 252: f(x)= 0.2218596816503148
# differential_evolution step 253: f(x)= 0.2218596816503148
# differential_evolution step 254: f(x)= 0.2218596816503148
# differential_evolution step 255: f(x)= 0.2218596816503148
# differential_evolution step 256: f(x)= 0.2218596816503148
# differential_evolution step 257: f(x)= 0.2218596816503148
# differential_evolution step 258: f(x)= 0.2218596816503148
# differential_evolution step 259: f(x)= 0.2218596816503148
# differential_evolution step 260: f(x)= 0.2218596816503148
# differential_evolution step 261: f(x)= 0.2218596816503148
# differential_evolution step 262: f(x)= 0.2218596816503148
# differential_evolution step 263: f(x)= 0.2218596816503148
# differential_evolution step 264: f(x)= 0.2218596816503148
# differential_evolution step 265: f(x)= 0.2218596816503148
# differential_evolution step 266: f(x)= 0.2218596816503148
# differential_evolution step 267: f(x)= 0.21919330223577743
# differential_evolution step 268: f(x)= 0.21919330223577743
# differential_evolution step 269: f(x)= 0.21919330223577743
# differential_evolution step 270: f(x)= 0.21919330223577743
# differential_evolution step 271: f(x)= 0.21919330223577743
# differential_evolution step 272: f(x)= 0.21919330223577743
# differential_evolution step 273: f(x)= 0.20765905002354396
# differential_evolution step 274: f(x)= 0.20765905002354396
# differential_evolution step 275: f(x)= 0.20765905002354396
# differential_evolution step 276: f(x)= 0.20765905002354396
# differential_evolution step 277: f(x)= 0.20765905002354396
# differential_evolution step 278: f(x)= 0.20765905002354396
# differential_evolution step 279: f(x)= 0.20765905002354396
# differential_evolution step 280: f(x)= 0.20765905002354396
# differential_evolution step 281: f(x)= 0.20765905002354396
# differential_evolution step 282: f(x)= 0.20765905002354396
# differential_evolution step 283: f(x)= 0.20765905002354396
# differential_evolution step 284: f(x)= 0.17939423134276183
# differential_evolution step 285: f(x)= 0.17939423134276183
# differential_evolution step 286: f(x)= 0.17939423134276183
# differential_evolution step 287: f(x)= 0.17939423134276183
# differential_evolution step 288: f(x)= 0.17365519983808853
# differential_evolution step 289: f(x)= 0.17365519983808853
# differential_evolution step 290: f(x)= 0.17365519983808853
# differential_evolution step 291: f(x)= 0.17365519983808853
# differential_evolution step 292: f(x)= 0.17365519983808853
# differential_evolution step 293: f(x)= 0.17365519983808853
# differential_evolution step 294: f(x)= 0.17365519983808853
# differential_evolution step 295: f(x)= 0.17365519983808853
# differential_evolution step 296: f(x)= 0.17365519983808853
# differential_evolution step 297: f(x)= 0.17365519983808853
# differential_evolution step 298: f(x)= 0.17365519983808853
# differential_evolution step 299: f(x)= 0.17365519983808853
# differential_evolution step 300: f(x)= 0.17365519983808853
# differential_evolution step 301: f(x)= 0.17365519983808853
# differential_evolution step 302: f(x)= 0.17365519983808853
# differential_evolution step 303: f(x)= 0.17365519983808853
# differential_evolution step 304: f(x)= 0.17365519983808853
# differential_evolution step 305: f(x)= 0.17365519983808853
# differential_evolution step 306: f(x)= 0.17365519983808853
# differential_evolution step 307: f(x)= 0.17365519983808853
# differential_evolution step 308: f(x)= 0.17365519983808853
# differential_evolution step 309: f(x)= 0.17365519983808853
# differential_evolution step 310: f(x)= 0.17365519983808853
# differential_evolution step 311: f(x)= 0.16958557004141295
# differential_evolution step 312: f(x)= 0.16958557004141295
# differential_evolution step 313: f(x)= 0.16958557004141295
# differential_evolution step 314: f(x)= 0.16958557004141295
# differential_evolution step 315: f(x)= 0.16958557004141295
# differential_evolution step 316: f(x)= 0.16958557004141295
# differential_evolution step 317: f(x)= 0.16958557004141295
# differential_evolution step 318: f(x)= 0.16958557004141295
# differential_evolution step 319: f(x)= 0.16958557004141295
# differential_evolution step 320: f(x)= 0.16958557004141295
# differential_evolution step 321: f(x)= 0.16668163038062808
# differential_evolution step 322: f(x)= 0.16668163038062808
# differential_evolution step 323: f(x)= 0.16668163038062808
# differential_evolution step 324: f(x)= 0.16590627925801815
# differential_evolution step 325: f(x)= 0.16590627925801815
# differential_evolution step 326: f(x)= 0.16590627925801815
# differential_evolution step 327: f(x)= 0.16590627925801815
# differential_evolution step 328: f(x)= 0.16116740514281486
# differential_evolution step 329: f(x)= 0.16116740514281486
# differential_evolution step 330: f(x)= 0.16116740514281486
# differential_evolution step 331: f(x)= 0.16116740514281486
# differential_evolution step 332: f(x)= 0.16116740514281486
# differential_evolution step 333: f(x)= 0.16116740514281486
# differential_evolution step 334: f(x)= 0.16116740514281486
# differential_evolution step 335: f(x)= 0.16116740514281486
# differential_evolution step 336: f(x)= 0.16116740514281486
# differential_evolution step 337: f(x)= 0.16116740514281486
# differential_evolution step 338: f(x)= 0.16116740514281486
# differential_evolution step 339: f(x)= 0.16116740514281486
# differential_evolution step 340: f(x)= 0.16116740514281486
# differential_evolution step 341: f(x)= 0.16116740514281486
# differential_evolution step 342: f(x)= 0.16116740514281486
# differential_evolution step 343: f(x)= 0.16116740514281486
# differential_evolution step 344: f(x)= 0.1607691662440216
# differential_evolution step 345: f(x)= 0.1607691662440216
# differential_evolution step 346: f(x)= 0.1607691662440216
# differential_evolution step 347: f(x)= 0.1607691662440216
# differential_evolution step 348: f(x)= 0.1589064199124643
# differential_evolution step 349: f(x)= 0.15811310810832888
# differential_evolution step 350: f(x)= 0.15811310810832888
# differential_evolution step 351: f(x)= 0.15811310810832888
# differential_evolution step 352: f(x)= 0.15811310810832888
# differential_evolution step 353: f(x)= 0.15811310810832888
# differential_evolution step 354: f(x)= 0.15811310810832888
# differential_evolution step 355: f(x)= 0.15811310810832888
# differential_evolution step 356: f(x)= 0.15811310810832888
# differential_evolution step 357: f(x)= 0.13467055037774628
# differential_evolution step 358: f(x)= 0.13467055037774628
# differential_evolution step 359: f(x)= 0.13467055037774628
# differential_evolution step 360: f(x)= 0.13467055037774628
# differential_evolution step 361: f(x)= 0.13467055037774628
# differential_evolution step 362: f(x)= 0.13467055037774628
# differential_evolution step 363: f(x)= 0.13467055037774628
# differential_evolution step 364: f(x)= 0.12719901350009832
# differential_evolution step 365: f(x)= 0.12719901350009832
# differential_evolution step 366: f(x)= 0.12719901350009832
# differential_evolution step 367: f(x)= 0.12719901350009832
# differential_evolution step 368: f(x)= 0.12719901350009832
# differential_evolution step 369: f(x)= 0.12719901350009832
# differential_evolution step 370: f(x)= 0.12719901350009832
# differential_evolution step 371: f(x)= 0.11888508702838316
# differential_evolution step 372: f(x)= 0.11888508702838316
# differential_evolution step 373: f(x)= 0.11888508702838316
# differential_evolution step 374: f(x)= 0.11888508702838316
# differential_evolution step 375: f(x)= 0.11888508702838316
# differential_evolution step 376: f(x)= 0.11888508702838316
# differential_evolution step 377: f(x)= 0.11888508702838316
# differential_evolution step 378: f(x)= 0.11888508702838316
# differential_evolution step 379: f(x)= 0.11888508702838316
# differential_evolution step 380: f(x)= 0.11888508702838316
# differential_evolution step 381: f(x)= 0.11888508702838316
# differential_evolution step 382: f(x)= 0.11888508702838316
# differential_evolution step 383: f(x)= 0.11888508702838316
# differential_evolution step 384: f(x)= 0.11888508702838316
# differential_evolution step 385: f(x)= 0.11888508702838316
# differential_evolution step 386: f(x)= 0.11888508702838316
# differential_evolution step 387: f(x)= 0.11888508702838316
# differential_evolution step 388: f(x)= 0.11888508702838316
# differential_evolution step 389: f(x)= 0.11888508702838316
# differential_evolution step 390: f(x)= 0.11888508702838316
# differential_evolution step 391: f(x)= 0.11888508702838316
# differential_evolution step 392: f(x)= 0.11888508702838316
# differential_evolution step 393: f(x)= 0.11888508702838316
# differential_evolution step 394: f(x)= 0.11888508702838316
# differential_evolution step 395: f(x)= 0.11888508702838316
# differential_evolution step 396: f(x)= 0.11888508702838316
# differential_evolution step 397: f(x)= 0.11888508702838316
# differential_evolution step 398: f(x)= 0.11888508702838316
# differential_evolution step 399: f(x)= 0.11888508702838316
# differential_evolution step 400: f(x)= 0.11888508702838316
# differential_evolution step 401: f(x)= 0.11888508702838316
# differential_evolution step 402: f(x)= 0.11888508702838316
# differential_evolution step 403: f(x)= 0.11888508702838316
# differential_evolution step 404: f(x)= 0.11888508702838316
# differential_evolution step 405: f(x)= 0.11888508702838316
# differential_evolution step 406: f(x)= 0.11888508702838316
# differential_evolution step 407: f(x)= 0.11888508702838316
# differential_evolution step 408: f(x)= 0.11888508702838316
# differential_evolution step 409: f(x)= 0.11888508702838316
# differential_evolution step 410: f(x)= 0.11888508702838316
# differential_evolution step 411: f(x)= 0.11888508702838316
# differential_evolution step 412: f(x)= 0.11888508702838316
# differential_evolution step 413: f(x)= 0.11888508702838316
# differential_evolution step 414: f(x)= 0.11888508702838316
# differential_evolution step 415: f(x)= 0.11888508702838316
# differential_evolution step 416: f(x)= 0.11888508702838316
# differential_evolution step 417: f(x)= 0.11888508702838316
# differential_evolution step 418: f(x)= 0.11888508702838316
# differential_evolution step 419: f(x)= 0.11888508702838316
# differential_evolution step 420: f(x)= 0.11888508702838316
# differential_evolution step 421: f(x)= 0.11888508702838316
# differential_evolution step 422: f(x)= 0.11888508702838316
# differential_evolution step 423: f(x)= 0.11888508702838316
# differential_evolution step 424: f(x)= 0.11133413171034812
# differential_evolution step 425: f(x)= 0.11133413171034812
# differential_evolution step 426: f(x)= 0.11133413171034812
# differential_evolution step 427: f(x)= 0.11133413171034812
# differential_evolution step 428: f(x)= 0.11133413171034812
# differential_evolution step 429: f(x)= 0.11133413171034812
# differential_evolution step 430: f(x)= 0.11133413171034812
# differential_evolution step 431: f(x)= 0.11133413171034812
# differential_evolution step 432: f(x)= 0.11133413171034812
# differential_evolution step 433: f(x)= 0.11133413171034812
# differential_evolution step 434: f(x)= 0.11133413171034812
# differential_evolution step 435: f(x)= 0.11133413171034812
# differential_evolution step 436: f(x)= 0.11133413171034812
# differential_evolution step 437: f(x)= 0.11133413171034812
# differential_evolution step 438: f(x)= 0.11133413171034812
# differential_evolution step 439: f(x)= 0.11133413171034812
# differential_evolution step 440: f(x)= 0.11133413171034812
# differential_evolution step 441: f(x)= 0.11133413171034812
# differential_evolution step 442: f(x)= 0.11133413171034812
# differential_evolution step 443: f(x)= 0.11133413171034812
# differential_evolution step 444: f(x)= 0.11133413171034812
# differential_evolution step 445: f(x)= 0.11133413171034812
# differential_evolution step 446: f(x)= 0.11133413171034812
# differential_evolution step 447: f(x)= 0.11133413171034812
# differential_evolution step 448: f(x)= 0.11133413171034812
# differential_evolution step 449: f(x)= 0.11133413171034812
# differential_evolution step 450: f(x)= 0.11133413171034812
# differential_evolution step 451: f(x)= 0.11133413171034812
# differential_evolution step 452: f(x)= 0.11133413171034812
# differential_evolution step 453: f(x)= 0.11133413171034812
# differential_evolution step 454: f(x)= 0.11133413171034812
# differential_evolution step 455: f(x)= 0.11133413171034812
# differential_evolution step 456: f(x)= 0.11133413171034812
# differential_evolution step 457: f(x)= 0.11133413171034812
# differential_evolution step 458: f(x)= 0.10948960404952521
# differential_evolution step 459: f(x)= 0.10948960404952521
# differential_evolution step 460: f(x)= 0.10948960404952521
# differential_evolution step 461: f(x)= 0.10948960404952521
# differential_evolution step 462: f(x)= 0.10749501725084157
# differential_evolution step 463: f(x)= 0.10749501725084157
# differential_evolution step 464: f(x)= 0.10749501725084157
# differential_evolution step 465: f(x)= 0.10749501725084157
# differential_evolution step 466: f(x)= 0.10749501725084157
# differential_evolution step 467: f(x)= 0.10749501725084157
# differential_evolution step 468: f(x)= 0.10387649625981032
# differential_evolution step 469: f(x)= 0.10387649625981032
# differential_evolution step 470: f(x)= 0.10387649625981032
# differential_evolution step 471: f(x)= 0.10387649625981032
# differential_evolution step 472: f(x)= 0.10378943220515491
# differential_evolution step 473: f(x)= 0.10378943220515491
# differential_evolution step 474: f(x)= 0.10378943220515491
# differential_evolution step 475: f(x)= 0.10378943220515491
# differential_evolution step 476: f(x)= 0.10378943220515491
# differential_evolution step 477: f(x)= 0.10378943220515491
# differential_evolution step 478: f(x)= 0.10378943220515491
# differential_evolution step 479: f(x)= 0.10378943220515491
# differential_evolution step 480: f(x)= 0.10277684054329993
# differential_evolution step 481: f(x)= 0.10277684054329993
# differential_evolution step 482: f(x)= 0.10277684054329993
# differential_evolution step 483: f(x)= 0.10277684054329993
# differential_evolution step 484: f(x)= 0.10277684054329993
# differential_evolution step 485: f(x)= 0.10277684054329993
# differential_evolution step 486: f(x)= 0.10277684054329993
# differential_evolution step 487: f(x)= 0.10277684054329993
# differential_evolution step 488: f(x)= 0.10277684054329993
# differential_evolution step 489: f(x)= 0.10277684054329993
# differential_evolution step 490: f(x)= 0.10277684054329993
# differential_evolution step 491: f(x)= 0.10277684054329993
# differential_evolution step 492: f(x)= 0.10277684054329993
# differential_evolution step 493: f(x)= 0.10277684054329993
# differential_evolution step 494: f(x)= 0.10277684054329993
# differential_evolution step 495: f(x)= 0.10277684054329993
# differential_evolution step 496: f(x)= 0.0991009616343065
# differential_evolution step 497: f(x)= 0.0991009616343065
# differential_evolution step 498: f(x)= 0.0991009616343065
# differential_evolution step 499: f(x)= 0.0991009616343065
# differential_evolution step 500: f(x)= 0.0991009616343065
# differential_evolution step 501: f(x)= 0.0991009616343065
# differential_evolution step 502: f(x)= 0.0991009616343065
# differential_evolution step 503: f(x)= 0.0991009616343065
# differential_evolution step 504: f(x)= 0.0991009616343065
# differential_evolution step 505: f(x)= 0.09757973512708995
# differential_evolution step 506: f(x)= 0.09757973512708995
# differential_evolution step 507: f(x)= 0.09757973512708995
# differential_evolution step 508: f(x)= 0.09757973512708995
# differential_evolution step 509: f(x)= 0.09757973512708995
# differential_evolution step 510: f(x)= 0.09757973512708995
# differential_evolution step 511: f(x)= 0.09757973512708995
# differential_evolution step 512: f(x)= 0.09757973512708995
# differential_evolution step 513: f(x)= 0.09757973512708995
# differential_evolution step 514: f(x)= 0.09757973512708995
# differential_evolution step 515: f(x)= 0.09757973512708995
# differential_evolution step 516: f(x)= 0.09757973512708995
# differential_evolution step 517: f(x)= 0.09757973512708995
# differential_evolution step 518: f(x)= 0.09757973512708995
# differential_evolution step 519: f(x)= 0.09757973512708995
# differential_evolution step 520: f(x)= 0.09757973512708995
# differential_evolution step 521: f(x)= 0.09757973512708995
# differential_evolution step 522: f(x)= 0.09757973512708995
# differential_evolution step 523: f(x)= 0.09757973512708995
# differential_evolution step 524: f(x)= 0.09757973512708995
# differential_evolution step 525: f(x)= 0.09757973512708995
# differential_evolution step 526: f(x)= 0.09757973512708995
# differential_evolution step 527: f(x)= 0.09757973512708995
# differential_evolution step 528: f(x)= 0.09757973512708995
# differential_evolution step 529: f(x)= 0.09757973512708995
# differential_evolution step 530: f(x)= 0.09757973512708995
# differential_evolution step 531: f(x)= 0.09757973512708995
# differential_evolution step 532: f(x)= 0.09757973512708995
# differential_evolution step 533: f(x)= 0.09757973512708995
# differential_evolution step 534: f(x)= 0.09757973512708995
# differential_evolution step 535: f(x)= 0.09757973512708995
# differential_evolution step 536: f(x)= 0.09757973512708995
# differential_evolution step 537: f(x)= 0.09757973512708995
# differential_evolution step 538: f(x)= 0.09757973512708995
# differential_evolution step 539: f(x)= 0.09757973512708995
# differential_evolution step 540: f(x)= 0.09757973512708995
# differential_evolution step 541: f(x)= 0.09757973512708995
# differential_evolution step 542: f(x)= 0.09757973512708995
# differential_evolution step 543: f(x)= 0.09757973512708995
# differential_evolution step 544: f(x)= 0.09757973512708995
# differential_evolution step 545: f(x)= 0.09757973512708995
# differential_evolution step 546: f(x)= 0.09757973512708995
# differential_evolution step 547: f(x)= 0.09757973512708995
# differential_evolution step 548: f(x)= 0.09757973512708995
# differential_evolution step 549: f(x)= 0.09757973512708995
# differential_evolution step 550: f(x)= 0.09757973512708995
# differential_evolution step 551: f(x)= 0.09757973512708995
# differential_evolution step 552: f(x)= 0.09757973512708995
# differential_evolution step 553: f(x)= 0.09757973512708995
# differential_evolution step 554: f(x)= 0.09757973512708995
# differential_evolution step 555: f(x)= 0.09757973512708995
# differential_evolution step 556: f(x)= 0.09732491258807854
# differential_evolution step 557: f(x)= 0.09732491258807854
# differential_evolution step 558: f(x)= 0.09732491258807854
# differential_evolution step 559: f(x)= 0.09732491258807854
# differential_evolution step 560: f(x)= 0.09732491258807854
# differential_evolution step 561: f(x)= 0.09732491258807854
# differential_evolution step 562: f(x)= 0.09732491258807854
# differential_evolution step 563: f(x)= 0.09732491258807854
# differential_evolution step 564: f(x)= 0.09732491258807854
# differential_evolution step 565: f(x)= 0.09732491258807854
# differential_evolution step 566: f(x)= 0.09732491258807854
# differential_evolution step 567: f(x)= 0.09732491258807854
# differential_evolution step 568: f(x)= 0.09732491258807854
# differential_evolution step 569: f(x)= 0.09732491258807854
# differential_evolution step 570: f(x)= 0.09732491258807854
# differential_evolution step 571: f(x)= 0.09732491258807854
# differential_evolution step 572: f(x)= 0.09732491258807854
# differential_evolution step 573: f(x)= 0.09732491258807854
# differential_evolution step 574: f(x)= 0.09732491258807854
# differential_evolution step 575: f(x)= 0.09732491258807854
# differential_evolution step 576: f(x)= 0.09732491258807854
# differential_evolution step 577: f(x)= 0.09630558547656554
# differential_evolution step 578: f(x)= 0.09630558547656554
# differential_evolution step 579: f(x)= 0.09630558547656554
# differential_evolution step 580: f(x)= 0.09630558547656554
# differential_evolution step 581: f(x)= 0.09630558547656554
# differential_evolution step 582: f(x)= 0.09630558547656554
# differential_evolution step 583: f(x)= 0.09630558547656554
# differential_evolution step 584: f(x)= 0.09630558547656554
# differential_evolution step 585: f(x)= 0.09630558547656554
# differential_evolution step 586: f(x)= 0.09630558547656554
# differential_evolution step 587: f(x)= 0.09630558547656554
# differential_evolution step 588: f(x)= 0.09630558547656554
# differential_evolution step 589: f(x)= 0.09630558547656554
# differential_evolution step 590: f(x)= 0.09630558547656554
# differential_evolution step 591: f(x)= 0.09630558547656554
# differential_evolution step 592: f(x)= 0.09630558547656554
# differential_evolution step 593: f(x)= 0.09630558547656554
# differential_evolution step 594: f(x)= 0.09630558547656554
# differential_evolution step 595: f(x)= 0.09630558547656554
# differential_evolution step 596: f(x)= 0.09630558547656554
# differential_evolution step 597: f(x)= 0.09630558547656554
# differential_evolution step 598: f(x)= 0.09630558547656554
# differential_evolution step 599: f(x)= 0.09630558547656554
# differential_evolution step 600: f(x)= 0.09630558547656554
# differential_evolution step 601: f(x)= 0.09630558547656554
# differential_evolution step 602: f(x)= 0.09630558547656554
# differential_evolution step 603: f(x)= 0.09630558547656554
# differential_evolution step 604: f(x)= 0.09630558547656554
# differential_evolution step 605: f(x)= 0.09586919554955019
# differential_evolution step 606: f(x)= 0.09586919554955019
# differential_evolution step 607: f(x)= 0.09413054767753283
# differential_evolution step 608: f(x)= 0.09413054767753283
# differential_evolution step 609: f(x)= 0.09413054767753283
# differential_evolution step 610: f(x)= 0.09413054767753283
# differential_evolution step 611: f(x)= 0.09413054767753283
# differential_evolution step 612: f(x)= 0.09413054767753283
# differential_evolution step 613: f(x)= 0.09413054767753283
# differential_evolution step 614: f(x)= 0.09413054767753283
# differential_evolution step 615: f(x)= 0.09413054767753283
# differential_evolution step 616: f(x)= 0.09413054767753283
# differential_evolution step 617: f(x)= 0.09413054767753283
# differential_evolution step 618: f(x)= 0.09413054767753283
# differential_evolution step 619: f(x)= 0.09413054767753283
# differential_evolution step 620: f(x)= 0.09413054767753283
# differential_evolution step 621: f(x)= 0.09413054767753283
# differential_evolution step 622: f(x)= 0.09413054767753283
# differential_evolution step 623: f(x)= 0.09388394206778121
# differential_evolution step 624: f(x)= 0.09388394206778121
# differential_evolution step 625: f(x)= 0.09388394206778121
# differential_evolution step 626: f(x)= 0.09388394206778121
# differential_evolution step 627: f(x)= 0.09388394206778121
# differential_evolution step 628: f(x)= 0.09388394206778121
# differential_evolution step 629: f(x)= 0.09388394206778121
# differential_evolution step 630: f(x)= 0.09388394206778121
# differential_evolution step 631: f(x)= 0.09388394206778121
# differential_evolution step 632: f(x)= 0.09388394206778121
# differential_evolution step 633: f(x)= 0.0932514785633897
# differential_evolution step 634: f(x)= 0.0932514785633897
# differential_evolution step 635: f(x)= 0.0932514785633897
# differential_evolution step 636: f(x)= 0.0932514785633897
# differential_evolution step 637: f(x)= 0.0932514785633897
# differential_evolution step 638: f(x)= 0.0932514785633897
# differential_evolution step 639: f(x)= 0.0932514785633897
# differential_evolution step 640: f(x)= 0.0932514785633897
# differential_evolution step 641: f(x)= 0.0932514785633897
# differential_evolution step 642: f(x)= 0.0932514785633897
# differential_evolution step 643: f(x)= 0.09291105439908531
# differential_evolution step 644: f(x)= 0.09291105439908531
# differential_evolution step 645: f(x)= 0.09291105439908531
# differential_evolution step 646: f(x)= 0.09291105439908531
# differential_evolution step 647: f(x)= 0.09291105439908531
# differential_evolution step 648: f(x)= 0.09291105439908531
# differential_evolution step 649: f(x)= 0.09291105439908531
# differential_evolution step 650: f(x)= 0.09291105439908531
# differential_evolution step 651: f(x)= 0.09291105439908531
# differential_evolution step 652: f(x)= 0.09291105439908531
# differential_evolution step 653: f(x)= 0.09291105439908531
# differential_evolution step 654: f(x)= 0.09291105439908531
# differential_evolution step 655: f(x)= 0.09291105439908531
# differential_evolution step 656: f(x)= 0.09291105439908531
# differential_evolution step 657: f(x)= 0.09291105439908531
# differential_evolution step 658: f(x)= 0.09291105439908531
# differential_evolution step 659: f(x)= 0.09291105439908531
# differential_evolution step 660: f(x)= 0.09291105439908531
# differential_evolution step 661: f(x)= 0.09291105439908531
# differential_evolution step 662: f(x)= 0.09291105439908531
# differential_evolution step 663: f(x)= 0.09291105439908531
# differential_evolution step 664: f(x)= 0.09291105439908531
# differential_evolution step 665: f(x)= 0.09206328348404916
# differential_evolution step 666: f(x)= 0.09206328348404916
# differential_evolution step 667: f(x)= 0.09206328348404916
# differential_evolution step 668: f(x)= 0.09206328348404916
# differential_evolution step 669: f(x)= 0.09206328348404916
# differential_evolution step 670: f(x)= 0.09206328348404916
# differential_evolution step 671: f(x)= 0.09206328348404916
# differential_evolution step 672: f(x)= 0.09206328348404916
# differential_evolution step 673: f(x)= 0.09206328348404916
# differential_evolution step 674: f(x)= 0.09206328348404916
# differential_evolution step 675: f(x)= 0.09206328348404916
# differential_evolution step 676: f(x)= 0.09206328348404916
# differential_evolution step 677: f(x)= 0.09155858962424868
# differential_evolution step 678: f(x)= 0.09155858962424868
# differential_evolution step 679: f(x)= 0.09155858962424868
# differential_evolution step 680: f(x)= 0.09155858962424868
# differential_evolution step 681: f(x)= 0.09155858962424868
# differential_evolution step 682: f(x)= 0.09155858962424868
# differential_evolution step 683: f(x)= 0.09155858962424868
# differential_evolution step 684: f(x)= 0.09155858962424868
# differential_evolution step 685: f(x)= 0.09155858962424868
# differential_evolution step 686: f(x)= 0.09155858962424868
# differential_evolution step 687: f(x)= 0.09155858962424868
# differential_evolution step 688: f(x)= 0.09155858962424868
# differential_evolution step 689: f(x)= 0.09155858962424868
# differential_evolution step 690: f(x)= 0.09155858962424868
# differential_evolution step 691: f(x)= 0.09155858962424868
# differential_evolution step 692: f(x)= 0.09155858962424868
# differential_evolution step 693: f(x)= 0.09155858962424868
# differential_evolution step 694: f(x)= 0.09155858962424868
# differential_evolution step 695: f(x)= 0.09155858962424868
# differential_evolution step 696: f(x)= 0.09155858962424868
# differential_evolution step 697: f(x)= 0.09155858962424868
# differential_evolution step 698: f(x)= 0.09155858962424868
# differential_evolution step 699: f(x)= 0.09155858962424868
# differential_evolution step 700: f(x)= 0.09155858962424868
# differential_evolution step 701: f(x)= 0.09155858962424868
# differential_evolution step 702: f(x)= 0.09155858962424868
# differential_evolution step 703: f(x)= 0.09155858962424868
# differential_evolution step 704: f(x)= 0.09155858962424868
# differential_evolution step 705: f(x)= 0.09155858962424868
# differential_evolution step 706: f(x)= 0.09155858962424868
# differential_evolution step 707: f(x)= 0.09155858962424868
# differential_evolution step 708: f(x)= 0.09155858962424868
# differential_evolution step 709: f(x)= 0.09155858962424868
# differential_evolution step 710: f(x)= 0.09155858962424868
# differential_evolution step 711: f(x)= 0.09155858962424868
# differential_evolution step 712: f(x)= 0.09155858962424868
# differential_evolution step 713: f(x)= 0.09155858962424868
# differential_evolution step 714: f(x)= 0.09155858962424868
# differential_evolution step 715: f(x)= 0.09155858962424868
# differential_evolution step 716: f(x)= 0.09155858962424868
# differential_evolution step 717: f(x)= 0.09155858962424868
# differential_evolution step 718: f(x)= 0.09155858962424868
# differential_evolution step 719: f(x)= 0.09155858962424868
# differential_evolution step 720: f(x)= 0.09155858962424868
# differential_evolution step 721: f(x)= 0.09155858962424868
# differential_evolution step 722: f(x)= 0.09155858962424868
# differential_evolution step 723: f(x)= 0.09155858962424868
# differential_evolution step 724: f(x)= 0.09155858962424868
# differential_evolution step 725: f(x)= 0.09155858962424868
# differential_evolution step 726: f(x)= 0.09043219107731926
# differential_evolution step 727: f(x)= 0.09043219107731926
# differential_evolution step 728: f(x)= 0.09043219107731926
# differential_evolution step 729: f(x)= 0.09043219107731926
# differential_evolution step 730: f(x)= 0.09043219107731926
# differential_evolution step 731: f(x)= 0.09043219107731926
# differential_evolution step 732: f(x)= 0.09043219107731926
# differential_evolution step 733: f(x)= 0.09043219107731926
# differential_evolution step 734: f(x)= 0.09043219107731926
# differential_evolution step 735: f(x)= 0.09043219107731926
# differential_evolution step 736: f(x)= 0.09043219107731926
# differential_evolution step 737: f(x)= 0.09043219107731926
# differential_evolution step 738: f(x)= 0.09043219107731926
# differential_evolution step 739: f(x)= 0.09043219107731926
# differential_evolution step 740: f(x)= 0.09043219107731926
# differential_evolution step 741: f(x)= 0.09043219107731926
# differential_evolution step 742: f(x)= 0.09043219107731926
# differential_evolution step 743: f(x)= 0.09043219107731926
# differential_evolution step 744: f(x)= 0.09043219107731926
# differential_evolution step 745: f(x)= 0.09043219107731926
# differential_evolution step 746: f(x)= 0.09043219107731926
# differential_evolution step 747: f(x)= 0.09043219107731926
# differential_evolution step 748: f(x)= 0.09043219107731926
# differential_evolution step 749: f(x)= 0.09043219107731926
# differential_evolution step 750: f(x)= 0.09043219107731926
# differential_evolution step 751: f(x)= 0.09043219107731926
# differential_evolution step 752: f(x)= 0.09043219107731926
# differential_evolution step 753: f(x)= 0.09043219107731926
# differential_evolution step 754: f(x)= 0.09043219107731926
# differential_evolution step 755: f(x)= 0.09043219107731926
# differential_evolution step 756: f(x)= 0.09043219107731926
# differential_evolution step 757: f(x)= 0.09043219107731926
# differential_evolution step 758: f(x)= 0.09043219107731926
# differential_evolution step 759: f(x)= 0.09043219107731926
# differential_evolution step 760: f(x)= 0.09043219107731926
# differential_evolution step 761: f(x)= 0.09043219107731926
# differential_evolution step 762: f(x)= 0.09043219107731926
# differential_evolution step 763: f(x)= 0.09016398504615843
# differential_evolution step 764: f(x)= 0.09016398504615843
# differential_evolution step 765: f(x)= 0.09016398504615843
# differential_evolution step 766: f(x)= 0.09015560674711831
# differential_evolution step 767: f(x)= 0.09009116618642124
# differential_evolution step 768: f(x)= 0.09009116618642124
# differential_evolution step 769: f(x)= 0.09009116618642124
# differential_evolution step 770: f(x)= 0.09009116618642124
# differential_evolution step 771: f(x)= 0.09009116618642124
# differential_evolution step 772: f(x)= 0.09009116618642124
# differential_evolution step 773: f(x)= 0.09009116618642124
# differential_evolution step 774: f(x)= 0.09009116618642124
# differential_evolution step 775: f(x)= 0.09009116618642124
# differential_evolution step 776: f(x)= 0.09009116618642124
# differential_evolution step 777: f(x)= 0.09009116618642124
# differential_evolution step 778: f(x)= 0.0897827996849656
# differential_evolution step 779: f(x)= 0.0897827996849656
# differential_evolution step 780: f(x)= 0.0897827996849656
# differential_evolution step 781: f(x)= 0.0897827996849656
# differential_evolution step 782: f(x)= 0.0897827996849656
# differential_evolution step 783: f(x)= 0.0897827996849656
# differential_evolution step 784: f(x)= 0.0897827996849656
# differential_evolution step 785: f(x)= 0.0897827996849656
# differential_evolution step 786: f(x)= 0.0892617511080914
# differential_evolution step 787: f(x)= 0.0892617511080914
# differential_evolution step 788: f(x)= 0.0892617511080914
# differential_evolution step 789: f(x)= 0.0892617511080914
# differential_evolution step 790: f(x)= 0.0892617511080914
# differential_evolution step 791: f(x)= 0.0892617511080914
# differential_evolution step 792: f(x)= 0.0892617511080914
# differential_evolution step 793: f(x)= 0.0892617511080914
# differential_evolution step 794: f(x)= 0.0892617511080914
# differential_evolution step 795: f(x)= 0.0892617511080914
# differential_evolution step 796: f(x)= 0.0892617511080914
# differential_evolution step 797: f(x)= 0.0892617511080914
# differential_evolution step 798: f(x)= 0.0892617511080914
# differential_evolution step 799: f(x)= 0.0892617511080914
# differential_evolution step 800: f(x)= 0.0892617511080914
# differential_evolution step 801: f(x)= 0.0892617511080914
# differential_evolution step 802: f(x)= 0.0892617511080914
# differential_evolution step 803: f(x)= 0.0892617511080914
# differential_evolution step 804: f(x)= 0.0892617511080914
# differential_evolution step 805: f(x)= 0.0892617511080914
# differential_evolution step 806: f(x)= 0.0892617511080914
# differential_evolution step 807: f(x)= 0.0892617511080914
# differential_evolution step 808: f(x)= 0.08916305599911983
# differential_evolution step 809: f(x)= 0.08916305599911983
# differential_evolution step 810: f(x)= 0.08916305599911983
# differential_evolution step 811: f(x)= 0.08916305599911983
# differential_evolution step 812: f(x)= 0.08916305599911983
# differential_evolution step 813: f(x)= 0.08916305599911983
# differential_evolution step 814: f(x)= 0.08916305599911983
# differential_evolution step 815: f(x)= 0.08916305599911983
# differential_evolution step 816: f(x)= 0.08916305599911983
# differential_evolution step 817: f(x)= 0.08916305599911983
# differential_evolution step 818: f(x)= 0.08916305599911983
# differential_evolution step 819: f(x)= 0.08916305599911983
# differential_evolution step 820: f(x)= 0.08916305599911983
# differential_evolution step 821: f(x)= 0.08916305599911983
# differential_evolution step 822: f(x)= 0.08916305599911983
# differential_evolution step 823: f(x)= 0.08916305599911983
# differential_evolution step 824: f(x)= 0.08916305599911983
# differential_evolution step 825: f(x)= 0.08916305599911983
# differential_evolution step 826: f(x)= 0.08916305599911983
# differential_evolution step 827: f(x)= 0.08916305599911983
# differential_evolution step 828: f(x)= 0.08916305599911983
# differential_evolution step 829: f(x)= 0.08916305599911983
# differential_evolution step 830: f(x)= 0.08916305599911983
# differential_evolution step 831: f(x)= 0.08916305599911983
# differential_evolution step 832: f(x)= 0.08916305599911983
# differential_evolution step 833: f(x)= 0.08916305599911983
# differential_evolution step 834: f(x)= 0.08916305599911983
# differential_evolution step 835: f(x)= 0.08916305599911983
# differential_evolution step 836: f(x)= 0.08916305599911983
# differential_evolution step 837: f(x)= 0.08916305599911983
# differential_evolution step 838: f(x)= 0.08916305599911983
# differential_evolution step 839: f(x)= 0.08916305599911983
# differential_evolution step 840: f(x)= 0.08916305599911983
# differential_evolution step 841: f(x)= 0.08800258178744153
# differential_evolution step 842: f(x)= 0.08800258178744153
# differential_evolution step 843: f(x)= 0.08800258178744153
# differential_evolution step 844: f(x)= 0.08800258178744153
# differential_evolution step 845: f(x)= 0.08800258178744153
# differential_evolution step 846: f(x)= 0.08800258178744153
# differential_evolution step 847: f(x)= 0.08800258178744153
# differential_evolution step 848: f(x)= 0.08800258178744153
# differential_evolution step 849: f(x)= 0.08800258178744153
# differential_evolution step 850: f(x)= 0.08800258178744153
# differential_evolution step 851: f(x)= 0.08800258178744153
# differential_evolution step 852: f(x)= 0.08800258178744153
# differential_evolution step 853: f(x)= 0.08800258178744153
# differential_evolution step 854: f(x)= 0.08800258178744153
# differential_evolution step 855: f(x)= 0.08800258178744153
# differential_evolution step 856: f(x)= 0.08800258178744153
# differential_evolution step 857: f(x)= 0.08800258178744153
# differential_evolution step 858: f(x)= 0.08800258178744153
# differential_evolution step 859: f(x)= 0.08800258178744153
# differential_evolution step 860: f(x)= 0.08800258178744153
# differential_evolution step 861: f(x)= 0.08800258178744153
# differential_evolution step 862: f(x)= 0.08800258178744153
# differential_evolution step 863: f(x)= 0.08800258178744153
# differential_evolution step 864: f(x)= 0.08800258178744153
# differential_evolution step 865: f(x)= 0.08800258178744153
# differential_evolution step 866: f(x)= 0.08800258178744153
# differential_evolution step 867: f(x)= 0.08800258178744153
# differential_evolution step 868: f(x)= 0.08800258178744153
# differential_evolution step 869: f(x)= 0.08800258178744153
# differential_evolution step 870: f(x)= 0.08800258178744153
# differential_evolution step 871: f(x)= 0.08800258178744153
# differential_evolution step 872: f(x)= 0.08800258178744153
# differential_evolution step 873: f(x)= 0.08800258178744153
# differential_evolution step 874: f(x)= 0.08800258178744153
# differential_evolution step 875: f(x)= 0.08800258178744153
# differential_evolution step 876: f(x)= 0.08800258178744153
# differential_evolution step 877: f(x)= 0.08800258178744153
# differential_evolution step 878: f(x)= 0.08800258178744153
# differential_evolution step 879: f(x)= 0.08800258178744153
# differential_evolution step 880: f(x)= 0.08800258178744153
# differential_evolution step 881: f(x)= 0.08800258178744153
# differential_evolution step 882: f(x)= 0.08800258178744153
# differential_evolution step 883: f(x)= 0.08800258178744153
# differential_evolution step 884: f(x)= 0.08800258178744153
# differential_evolution step 885: f(x)= 0.08800258178744153
# differential_evolution step 886: f(x)= 0.08800258178744153
# differential_evolution step 887: f(x)= 0.08800258178744153
# differential_evolution step 888: f(x)= 0.08800258178744153
# differential_evolution step 889: f(x)= 0.08800258178744153
# differential_evolution step 890: f(x)= 0.08800258178744153
# differential_evolution step 891: f(x)= 0.08800258178744153
# differential_evolution step 892: f(x)= 0.08800258178744153
# differential_evolution step 893: f(x)= 0.08800258178744153
# differential_evolution step 894: f(x)= 0.08800258178744153
# differential_evolution step 895: f(x)= 0.08800258178744153
# differential_evolution step 896: f(x)= 0.08800258178744153
# differential_evolution step 897: f(x)= 0.08800258178744153
# differential_evolution step 898: f(x)= 0.08800258178744153
# differential_evolution step 899: f(x)= 0.08800258178744153
# differential_evolution step 900: f(x)= 0.08800258178744153
# differential_evolution step 901: f(x)= 0.08800258178744153
# differential_evolution step 902: f(x)= 0.08800258178744153
# differential_evolution step 903: f(x)= 0.08800258178744153
# differential_evolution step 904: f(x)= 0.08800258178744153
# differential_evolution step 905: f(x)= 0.08800258178744153
# differential_evolution step 906: f(x)= 0.08800258178744153
# differential_evolution step 907: f(x)= 0.08778347172825215
# differential_evolution step 908: f(x)= 0.08749059908182741
# differential_evolution step 909: f(x)= 0.08749059908182741
# differential_evolution step 910: f(x)= 0.08749059908182741
# differential_evolution step 911: f(x)= 0.08749059908182741
# differential_evolution step 912: f(x)= 0.08749059908182741
# differential_evolution step 913: f(x)= 0.08673724065248216
# differential_evolution step 914: f(x)= 0.08673724065248216
# differential_evolution step 915: f(x)= 0.08656073525726923
# differential_evolution step 916: f(x)= 0.08656073525726923
# differential_evolution step 917: f(x)= 0.08656073525726923
# differential_evolution step 918: f(x)= 0.08656073525726923
# differential_evolution step 919: f(x)= 0.08656073525726923
# differential_evolution step 920: f(x)= 0.08656073525726923
# differential_evolution step 921: f(x)= 0.08656073525726923
# differential_evolution step 922: f(x)= 0.0852206831479923
# differential_evolution step 923: f(x)= 0.0852206831479923
# differential_evolution step 924: f(x)= 0.0852206831479923
# differential_evolution step 925: f(x)= 0.0849593418827918
# differential_evolution step 926: f(x)= 0.0849593418827918
# differential_evolution step 927: f(x)= 0.0849593418827918
# differential_evolution step 928: f(x)= 0.0849593418827918
# differential_evolution step 929: f(x)= 0.0849593418827918
# differential_evolution step 930: f(x)= 0.0849593418827918
# differential_evolution step 931: f(x)= 0.0849593418827918
# differential_evolution step 932: f(x)= 0.0849593418827918
# differential_evolution step 933: f(x)= 0.08423613835542346
# differential_evolution step 934: f(x)= 0.08423613835542346
# differential_evolution step 935: f(x)= 0.08423613835542346
# differential_evolution step 936: f(x)= 0.08423613835542346
# differential_evolution step 937: f(x)= 0.08423613835542346
# differential_evolution step 938: f(x)= 0.08423613835542346
# differential_evolution step 939: f(x)= 0.08423613835542346
# differential_evolution step 940: f(x)= 0.08423613835542346
# differential_evolution step 941: f(x)= 0.08423613835542346
# differential_evolution step 942: f(x)= 0.08299033528742085
# differential_evolution step 943: f(x)= 0.08299033528742085
# differential_evolution step 944: f(x)= 0.08299033528742085
# differential_evolution step 945: f(x)= 0.08299033528742085
# differential_evolution step 946: f(x)= 0.08299033528742085
# differential_evolution step 947: f(x)= 0.08299033528742085
# differential_evolution step 948: f(x)= 0.08238408239465549
# differential_evolution step 949: f(x)= 0.08238408239465549
# differential_evolution step 950: f(x)= 0.08238408239465549
# differential_evolution step 951: f(x)= 0.08238408239465549
# differential_evolution step 952: f(x)= 0.08238408239465549
# differential_evolution step 953: f(x)= 0.08238408239465549
# differential_evolution step 954: f(x)= 0.08238408239465549
# differential_evolution step 955: f(x)= 0.08238408239465549
# differential_evolution step 956: f(x)= 0.08206295864453658
# differential_evolution step 957: f(x)= 0.08206295864453658
# differential_evolution step 958: f(x)= 0.08176191710747856
# differential_evolution step 959: f(x)= 0.07951953069366591
# differential_evolution step 960: f(x)= 0.07951953069366591
# differential_evolution step 961: f(x)= 0.07366051141985464
# differential_evolution step 962: f(x)= 0.07366051141985464
# differential_evolution step 963: f(x)= 0.07366051141985464
# differential_evolution step 964: f(x)= 0.07366051141985464
# differential_evolution step 965: f(x)= 0.07366051141985464
# differential_evolution step 966: f(x)= 0.07366051141985464
# differential_evolution step 967: f(x)= 0.07366051141985464
# differential_evolution step 968: f(x)= 0.07366051141985464
# differential_evolution step 969: f(x)= 0.07366051141985464
# differential_evolution step 970: f(x)= 0.07366051141985464
# differential_evolution step 971: f(x)= 0.07366051141985464
# differential_evolution step 972: f(x)= 0.07366051141985464
# differential_evolution step 973: f(x)= 0.07366051141985464
# differential_evolution step 974: f(x)= 0.07366051141985464
# differential_evolution step 975: f(x)= 0.07366051141985464
# differential_evolution step 976: f(x)= 0.07009773271249908
# differential_evolution step 977: f(x)= 0.07009773271249908
# differential_evolution step 978: f(x)= 0.07009773271249908
# differential_evolution step 979: f(x)= 0.07009773271249908
# differential_evolution step 980: f(x)= 0.07009773271249908
# differential_evolution step 981: f(x)= 0.06946814499908666
# differential_evolution step 982: f(x)= 0.06946814499908666
# differential_evolution step 983: f(x)= 0.06946814499908666
# differential_evolution step 984: f(x)= 0.06817941401037236
# differential_evolution step 985: f(x)= 0.06817941401037236
# differential_evolution step 986: f(x)= 0.06817941401037236
# differential_evolution step 987: f(x)= 0.06817941401037236
# differential_evolution step 988: f(x)= 0.06817941401037236
# differential_evolution step 989: f(x)= 0.06817941401037236
# differential_evolution step 990: f(x)= 0.06817941401037236
# differential_evolution step 991: f(x)= 0.06817941401037236
# differential_evolution step 992: f(x)= 0.06817941401037236
# differential_evolution step 993: f(x)= 0.06817941401037236
# differential_evolution step 994: f(x)= 0.06817941401037236
# differential_evolution step 995: f(x)= 0.06817941401037236
# differential_evolution step 996: f(x)= 0.06817941401037236
# differential_evolution step 997: f(x)= 0.06817941401037236
# differential_evolution step 998: f(x)= 0.06817941401037236
# differential_evolution step 999: f(x)= 0.06817941401037236
# differential_evolution step 1000: f(x)= 0.06817941401037236
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1865, r_e=3.3087, n=0.5355, x_0=24.6094
# Sérsic 2: I_e=0.1311, r_e=20.0000, n=0.3272, x_0=45.7116
# Sérsic 3: I_e=0.3712, r_e=0.6146, n=2.9957, x_0=59.0685
# Sérsic 4: I_e=0.0566, r_e=1.9155, n=0.8122, x_0=68.4371
# Sérsic 5: I_e=0.0495, r_e=9.8510, n=0.2708, x_0=102.3524
# Chi quadro minimo: 0.06002665615763582
# False

# %%
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=0.1865, r_e=3.3087, n=0.5355, x_0=24.6094
# Sérsic 2: I_e=0.1311, r_e=20.0000, n=0.3272, x_0=45.7116
# Sérsic 3: I_e=0.3712, r_e=0.6146, n=2.9957, x_0=59.0685
# Sérsic 4: I_e=0.0566, r_e=1.9155, n=0.8122, x_0=68.4371
# Sérsic 5: I_e=0.0495, r_e=9.8510, n=0.2708, x_0=102.3524
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = real_errors_OIII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0146, r_e=25.7763, n=2.4183, x_0=24.9189
# Sérsic 2: I_e=0.0643, r_e=20.0000, n=0.5713, x_0=46.7174
# Sérsic 3: I_e=0.2122, r_e=1.1190, n=3.1618, x_0=59.0685
# Sérsic 4: I_e=0.0243, r_e=17.1524, n=1.0167, x_0=68.0002
# Sérsic 5: I_e=0.0380, r_e=9.9999, n=0.3325, x_0=102.1606
# [3.38215026e-02 7.19559597e+01 1.47585795e+00 1.39397143e-01
#  8.70569413e-02 2.67451268e+01 4.87203312e-01 2.21803084e+01
#  1.62539702e+01 4.88142600e+01 4.09376979e+02 3.49440251e-02
#  4.68559662e-02 3.20384090e+01 9.58914021e-01 3.35543640e+00
#  1.37720040e-02 3.28967381e+00 2.34947536e-01 2.18498311e+00]
# 0.22831087291601906

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))
real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[2])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 10
#       8 x_axes = np.arange(0, 100, 1)
#       9 plt.figure(figsize=(8,6))
# ---> 10 plt.plot(x_axes, radial_profile_continuum_1)
#      11 plt.plot(x_axes, radial_profile_error_continuum_1)
#      12 plt.title(r'Continuum 1')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (120,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))
real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigmas[-1],
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[-1], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigmas[-1], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 =  (wv > 5950)*(wv < 6500)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3) #, bounds = bounds_list, maxfev = 10000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit_continuum.csv", index= False)

# %% [markdown]
# ## Halpha and continuum

# %%
mask_continuum_3 = (wv > 6550)*(wv < 6600)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_HA, label = 'Halpha') 
plt.plot(x_axes, radial_profile_continuum_3, label = 'Continuum')
plt.title(r'Halpha and Continuum UGC409')
plt.legend()
plt.xlabel('Pixel')
plt.ylabel(r'Flux [$10^{-16}$ erg/(cm$^2$ s Å)]')
plt.grid(alpha = 0.3)
plt.savefig('Halpha_continuum_UGC409')
