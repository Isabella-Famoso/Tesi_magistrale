# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/Spectra_extraction/redshift.txt")
z = red[4][0] 
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4228.18435644 4229.6393881  4231.09441976 ... 6973.82909277 6975.28412442
#  6976.73915608] [0.02273419 0.01297247 0.06154188 ... 0.0195174  0.01430345 0.02079502] [0.01118876 0.01118876 0.01118876 ... 0.01118876 0.01118876 0.01118876]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11409218 2.11481969 2.11554721 ... 3.48691455 3.48764206 3.48836958]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3337, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314399512

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        49        48
# chi2/DOF: 0.1447; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        32         1
# chi2/DOF: 0.04945; DOF: 2020; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([32.06291657,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         8         1
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5881; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.127      0.97     -25    33
# Comp:  1                 Hbeta      6.101      0.97     -25    33
# Comp:  1                Halpha      23.54      0.97     -25    33
# Comp:  2             [SII]6716      7.642      0.93     -31    16
# Comp:  2             [SII]6731      4.435      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.307      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.417       1.2     -31    16
# Comp:  2            [OI]6300_d      1.471       1.2     -31    16
# Comp:  2           [NII]6583_d      6.923       1.2     -31    16
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  5.648; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  8.877; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  33.66; gas flux:     32 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  11.33; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  6.951; gas flux:      6 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.951; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  7.443; gas flux:      7 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.746; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  7.972; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -26        36
#  comp.  2:       -32         3
# chi2/DOF: 0.5832; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.429      0.98     -26    36
# Comp:  1                 Hbeta      7.023      0.98     -26    36
# Comp:  1                Halpha      24.11      0.98     -26    36
# Comp:  2             [SII]6716      7.651      0.92     -32     3
# Comp:  2             [SII]6731      4.018      0.92     -32     3
# Comp:  2              HeII4687     0.1325      0.92     -32     3
# Comp:  2               HeI5876      1.339      0.92     -32     3
# Comp:  2          [OIII]5007_d      6.868       1.2     -32     3
# Comp:  2            [OI]6300_d      1.630       1.2     -32     3
# Comp:  2           [NII]6583_d      7.006       1.2     -32     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        13
#  comp.  1:       -24        34
#  comp.  2:       -31        13
# chi2/DOF: 0.5849; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.899      0.97     -24    34
# Comp:  1                 Hbeta      6.689      0.97     -24    34
# Comp:  1                Halpha      23.69      0.97     -24    34
# Comp:  2             [SII]6716      7.970      0.92     -31    13
# Comp:  2             [SII]6731      4.286      0.92     -31    13
# Comp:  2              HeII4687      0.000      0.92     -31    13
# Comp:  2               HeI5876      1.227      0.92     -31    13
# Comp:  2          [OIII]5007_d      6.576       1.2     -31    13
# Comp:  2            [OI]6300_d      1.116       1.2     -31    13
# Comp:  2           [NII]6583_d      7.104       1.2     -31    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        65
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5832; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.894      0.97     -25    33
# Comp:  1                 Hbeta      6.238      0.97     -25    33
# Comp:  1                Halpha      23.72      0.97     -25    33
# Comp:  2             [SII]6716      7.507      0.93     -31    16
# Comp:  2             [SII]6731      4.603      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.456      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.053       1.2     -31    16
# Comp:  2            [OI]6300_d      1.895       1.2     -31    16
# Comp:  2           [NII]6583_d      7.323       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        26
#  comp.  1:       -25        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5813; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.074      0.97     -25    33
# Comp:  1                 Hbeta      6.036      0.97     -25    33
# Comp:  1                Halpha      24.14      0.97     -25    33
# Comp:  2             [SII]6716      7.620      0.93     -31    17
# Comp:  2             [SII]6731      4.850      0.93     -31    17
# Comp:  2              HeII4687     0.4909      0.93     -31    17
# Comp:  2               HeI5876      1.331      0.93     -31    17
# Comp:  2          [OIII]5007_d      5.895       1.2     -31    17
# Comp:  2            [OI]6300_d      2.056       1.2     -31    17
# Comp:  2           [NII]6583_d      7.019       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        48
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5866; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.305      0.97     -25    33
# Comp:  1                 Hbeta      5.674      0.97     -25    33
# Comp:  1                Halpha      23.53      0.97     -25    33
# Comp:  2             [SII]6716      7.767      0.93     -31    16
# Comp:  2             [SII]6731      4.134      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.324      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.874       1.2     -31    16
# Comp:  2            [OI]6300_d      1.567       1.2     -31    16
# Comp:  2           [NII]6583_d      7.042       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        19
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5823; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.400      0.97     -25    33
# Comp:  1                 Hbeta      6.854      0.97     -25    33
# Comp:  1                Halpha      23.79      0.97     -25    33
# Comp:  2             [SII]6716      7.898      0.93     -31    16
# Comp:  2             [SII]6731      4.419      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.254      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.409       1.2     -31    16
# Comp:  2            [OI]6300_d      1.569       1.2     -31    16
# Comp:  2           [NII]6583_d      6.626       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -25        34
#  comp.  2:       -31         1
# chi2/DOF: 0.5834; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.613      0.97     -25    34
# Comp:  1                 Hbeta      7.562      0.97     -25    34
# Comp:  1                Halpha      24.21      0.97     -25    34
# Comp:  2             [SII]6716      7.408      0.92     -31     1
# Comp:  2             [SII]6731      3.951      0.92     -31     1
# Comp:  2              HeII4687      0.000      0.92     -31     1
# Comp:  2               HeI5876      1.202      0.92     -31     1
# Comp:  2          [OIII]5007_d      6.136       1.2     -31     1
# Comp:  2            [OI]6300_d      1.494       1.2     -31     1
# Comp:  2           [NII]6583_d      7.261       1.2     -31     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6       101
#  comp.  1:       -26        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5836; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.425      0.97     -26    33
# Comp:  1                 Hbeta      5.605      0.97     -26    33
# Comp:  1                Halpha      23.56      0.97     -26    33
# Comp:  2             [SII]6716      7.912      0.93     -31    16
# Comp:  2             [SII]6731      4.182      0.93     -31    16
# Comp:  2              HeII4687    0.08931      0.93     -31    16
# Comp:  2               HeI5876      1.293      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.078       1.2     -31    16
# Comp:  2            [OI]6300_d      1.615       1.2     -31    16
# Comp:  2           [NII]6583_d      6.491       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        58
#  comp.  1:       -26        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5838; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.966      0.97     -26    33
# Comp:  1                 Hbeta      6.389      0.97     -26    33
# Comp:  1                Halpha      24.06      0.97     -26    33
# Comp:  2             [SII]6716      7.583      0.93     -31    16
# Comp:  2             [SII]6731      4.166      0.93     -31    16
# Comp:  2              HeII4687     0.1529      0.93     -31    16
# Comp:  2               HeI5876      1.227      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.547       1.2     -31    16
# Comp:  2            [OI]6300_d      1.603       1.2     -31    16
# Comp:  2           [NII]6583_d      6.984       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        29
#  comp.  1:       -25        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5867; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.009      0.97     -25    33
# Comp:  1                 Hbeta      6.375      0.97     -25    33
# Comp:  1                Halpha      23.61      0.97     -25    33
# Comp:  2             [SII]6716      7.513      0.93     -31    17
# Comp:  2             [SII]6731      4.421      0.93     -31    17
# Comp:  2              HeII4687    0.04215      0.93     -31    17
# Comp:  2               HeI5876      1.035      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.670       1.2     -31    17
# Comp:  2            [OI]6300_d      1.319       1.2     -31    17
# Comp:  2           [NII]6583_d      6.725       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        33
#  comp.  1:       -26        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5847; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.477      0.97     -26    33
# Comp:  1                 Hbeta      6.723      0.97     -26    33
# Comp:  1                Halpha      24.14      0.97     -26    33
# Comp:  2             [SII]6716      7.805      0.93     -31    16
# Comp:  2             [SII]6731      4.037      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.047      0.93     -31    16
# Comp:  2          [OIII]5007_d      7.113       1.2     -31    16
# Comp:  2            [OI]6300_d      1.409       1.2     -31    16
# Comp:  2           [NII]6583_d      6.672       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        24
#  comp.  1:       -26        33
#  comp.  2:       -31        15
# chi2/DOF: 0.5852; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.426      0.97     -26    33
# Comp:  1                 Hbeta      6.990      0.97     -26    33
# Comp:  1                Halpha      24.13      0.97     -26    33
# Comp:  2             [SII]6716      7.638      0.93     -31    15
# Comp:  2             [SII]6731      4.565      0.93     -31    15
# Comp:  2              HeII4687      0.000      0.93     -31    15
# Comp:  2               HeI5876      1.271      0.93     -31    15
# Comp:  2          [OIII]5007_d      6.126       1.2     -31    15
# Comp:  2            [OI]6300_d      1.566       1.2     -31    15
# Comp:  2           [NII]6583_d      7.000       1.2     -31    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -24        36
#  comp.  2:       -34        18
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.221      0.98     -24    36
# Comp:  1                 Hbeta      6.809      0.98     -24    36
# Comp:  1                Halpha      23.94      0.98     -24    36
# Comp:  2             [SII]6716      7.269      0.93     -34    18
# Comp:  2             [SII]6731      4.427      0.93     -34    18
# Comp:  2              HeII4687      0.000      0.93     -34    18
# Comp:  2               HeI5876      1.323      0.93     -34    18
# Comp:  2          [OIII]5007_d      6.218       1.2     -34    18
# Comp:  2            [OI]6300_d      1.426       1.2     -34    18
# Comp:  2           [NII]6583_d      6.698       1.2     -34    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        66
#  comp.  1:       -27        35
#  comp.  2:       -38        20
# chi2/DOF: 0.5854; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.662      0.97     -27    35
# Comp:  1                 Hbeta      6.924      0.97     -27    35
# Comp:  1                Halpha      24.60      0.97     -27    35
# Comp:  2             [SII]6716      7.654      0.94     -38    20
# Comp:  2             [SII]6731      4.678      0.94     -38    20
# Comp:  2              HeII4687      0.000      0.94     -38    20
# Comp:  2               HeI5876      1.264      0.94     -38    20
# Comp:  2          [OIII]5007_d      5.868       1.2     -38    20
# Comp:  2            [OI]6300_d      1.615       1.2     -38    20
# Comp:  2           [NII]6583_d      7.241       1.2     -38    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        67
#  comp.  1:       -26        34
#  comp.  2:       -31        15
# chi2/DOF: 0.5852; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.380      0.97     -26    34
# Comp:  1                 Hbeta      5.884      0.97     -26    34
# Comp:  1                Halpha      23.71      0.97     -26    34
# Comp:  2             [SII]6716      7.539      0.93     -31    15
# Comp:  2             [SII]6731      4.236      0.93     -31    15
# Comp:  2              HeII4687      0.000      0.93     -31    15
# Comp:  2               HeI5876      1.259      0.93     -31    15
# Comp:  2          [OIII]5007_d      6.177       1.2     -31    15
# Comp:  2            [OI]6300_d      1.215       1.2     -31    15
# Comp:  2           [NII]6583_d      7.276       1.2     -31    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        17
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5852; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.023      0.97     -25    33
# Comp:  1                 Hbeta      7.110      0.97     -25    33
# Comp:  1                Halpha      23.86      0.97     -25    33
# Comp:  2             [SII]6716      7.619      0.93     -31    16
# Comp:  2             [SII]6731      4.533      0.93     -31    16
# Comp:  2              HeII4687     0.2015      0.93     -31    16
# Comp:  2               HeI5876      1.347      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.103       1.2     -31    16
# Comp:  2            [OI]6300_d      1.709       1.2     -31    16
# Comp:  2           [NII]6583_d      7.039       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        40
#  comp.  1:       -25        33
#  comp.  2:       -31        15
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.776      0.97     -25    33
# Comp:  1                 Hbeta      6.317      0.97     -25    33
# Comp:  1                Halpha      23.76      0.97     -25    33
# Comp:  2             [SII]6716      7.681      0.93     -31    15
# Comp:  2             [SII]6731      4.223      0.93     -31    15
# Comp:  2              HeII4687      0.000      0.93     -31    15
# Comp:  2               HeI5876      1.095      0.93     -31    15
# Comp:  2          [OIII]5007_d      6.284       1.2     -31    15
# Comp:  2            [OI]6300_d      1.070       1.2     -31    15
# Comp:  2           [NII]6583_d      6.638       1.2     -31    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -26        35
#  comp.  2:       -31        29
# chi2/DOF: 0.5832; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.198      0.97     -26    35
# Comp:  1                 Hbeta      6.160      0.97     -26    35
# Comp:  1                Halpha      24.08      0.97     -26    35
# Comp:  2             [SII]6716      8.187      0.96     -31    29
# Comp:  2             [SII]6731      5.083      0.96     -31    29
# Comp:  2              HeII4687    0.08727      0.96     -31    29
# Comp:  2               HeI5876      1.436      0.96     -31    29
# Comp:  2          [OIII]5007_d      7.190       1.2     -31    29
# Comp:  2            [OI]6300_d      1.384       1.2     -31    29
# Comp:  2           [NII]6583_d      7.261       1.2     -31    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:       -24        33
#  comp.  2:       -30        14
# chi2/DOF: 0.5854; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.664      0.97     -24    33
# Comp:  1                 Hbeta      6.556      0.97     -24    33
# Comp:  1                Halpha      23.52      0.97     -24    33
# Comp:  2             [SII]6716      7.223      0.93     -30    14
# Comp:  2             [SII]6731      4.131      0.93     -30    14
# Comp:  2              HeII4687     0.3657      0.93     -30    14
# Comp:  2               HeI5876      1.222      0.93     -30    14
# Comp:  2          [OIII]5007_d      6.445       1.2     -30    14
# Comp:  2            [OI]6300_d     0.8959       1.2     -30    14
# Comp:  2           [NII]6583_d      6.858       1.2     -30    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -24        39
#  comp.  2:       -31        15
# chi2/DOF: 0.5841; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.659      0.99     -24    39
# Comp:  1                 Hbeta      6.795      0.99     -24    39
# Comp:  1                Halpha      24.44      0.99     -24    39
# Comp:  2             [SII]6716      7.543      0.93     -31    15
# Comp:  2             [SII]6731      4.683      0.93     -31    15
# Comp:  2              HeII4687      0.000      0.93     -31    15
# Comp:  2               HeI5876      1.136      0.93     -31    15
# Comp:  2          [OIII]5007_d      6.215       1.2     -31    15
# Comp:  2            [OI]6300_d     0.8502       1.2     -31    15
# Comp:  2           [NII]6583_d      6.701       1.2     -31    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:       -23        35
#  comp.  2:       -30        13
# chi2/DOF: 0.5837; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.458      0.97     -23    35
# Comp:  1                 Hbeta      5.866      0.97     -23    35
# Comp:  1                Halpha      23.49      0.97     -23    35
# Comp:  2             [SII]6716      7.821      0.92     -30    13
# Comp:  2             [SII]6731      4.387      0.92     -30    13
# Comp:  2              HeII4687      0.000      0.92     -30    13
# Comp:  2               HeI5876      1.228      0.92     -30    13
# Comp:  2          [OIII]5007_d      6.298       1.2     -30    13
# Comp:  2            [OI]6300_d      1.763       1.2     -30    13
# Comp:  2           [NII]6583_d      6.881       1.2     -30    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8         1
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5863; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.317      0.97     -25    33
# Comp:  1                 Hbeta      6.353      0.97     -25    33
# Comp:  1                Halpha      23.62      0.97     -25    33
# Comp:  2             [SII]6716      7.693      0.93     -31    16
# Comp:  2             [SII]6731      4.704      0.93     -31    16
# Comp:  2              HeII4687     0.1750      0.93     -31    16
# Comp:  2               HeI5876      1.359      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.212       1.2     -31    16
# Comp:  2            [OI]6300_d      1.058       1.2     -31    16
# Comp:  2           [NII]6583_d      6.904       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -27        33
#  comp.  2:       -31        27
# chi2/DOF: 0.5826; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.719      0.97     -27    33
# Comp:  1                 Hbeta      6.633      0.97     -27    33
# Comp:  1                Halpha      23.59      0.97     -27    33
# Comp:  2             [SII]6716      8.287      0.95     -31    27
# Comp:  2             [SII]6731      4.542      0.95     -31    27
# Comp:  2              HeII4687      0.000      0.95     -31    27
# Comp:  2               HeI5876      1.221      0.95     -31    27
# Comp:  2          [OIII]5007_d      6.021       1.2     -31    27
# Comp:  2            [OI]6300_d      1.797       1.2     -31    27
# Comp:  2           [NII]6583_d      7.175       1.2     -31    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        33
#  comp.  1:       -26        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5823; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.697      0.97     -26    33
# Comp:  1                 Hbeta      4.962      0.97     -26    33
# Comp:  1                Halpha      23.26      0.97     -26    33
# Comp:  2             [SII]6716      7.850      0.93     -31    17
# Comp:  2             [SII]6731      4.813      0.93     -31    17
# Comp:  2              HeII4687     0.1535      0.93     -31    17
# Comp:  2               HeI5876      1.271      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.088       1.2     -31    17
# Comp:  2            [OI]6300_d      1.703       1.2     -31    17
# Comp:  2           [NII]6583_d      6.769       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:       -27        33
#  comp.  2:       -29        13
# chi2/DOF: 0.5835; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.171      0.97     -27    33
# Comp:  1                 Hbeta      6.189      0.97     -27    33
# Comp:  1                Halpha      23.77      0.97     -27    33
# Comp:  2             [SII]6716      7.810      0.92     -29    13
# Comp:  2             [SII]6731      4.249      0.92     -29    13
# Comp:  2              HeII4687    0.02354      0.92     -29    13
# Comp:  2               HeI5876      1.621      0.92     -29    13
# Comp:  2          [OIII]5007_d      6.417       1.2     -29    13
# Comp:  2            [OI]6300_d      1.279       1.2     -29    13
# Comp:  2           [NII]6583_d      7.098       1.2     -29    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        26
#  comp.  1:       -25        33
#  comp.  2:       -31        18
# chi2/DOF: 0.5833; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.911      0.97     -25    33
# Comp:  1                 Hbeta      6.225      0.97     -25    33
# Comp:  1                Halpha      23.61      0.97     -25    33
# Comp:  2             [SII]6716      7.396      0.93     -31    18
# Comp:  2             [SII]6731      4.492      0.93     -31    18
# Comp:  2              HeII4687    0.06857      0.93     -31    18
# Comp:  2               HeI5876      1.276      0.93     -31    18
# Comp:  2          [OIII]5007_d      6.757       1.2     -31    18
# Comp:  2            [OI]6300_d      1.386       1.2     -31    18
# Comp:  2           [NII]6583_d      6.835       1.2     -31    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -26        37
#  comp.  2:       -33        26
# chi2/DOF: 0.5857; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.909      0.98     -26    37
# Comp:  1                 Hbeta      6.598      0.98     -26    37
# Comp:  1                Halpha      23.90      0.98     -26    37
# Comp:  2             [SII]6716      7.729      0.95     -33    26
# Comp:  2             [SII]6731      4.315      0.95     -33    26
# Comp:  2              HeII4687     0.3388      0.95     -33    26
# Comp:  2               HeI5876      1.163      0.95     -33    26
# Comp:  2          [OIII]5007_d      6.332       1.2     -33    26
# Comp:  2            [OI]6300_d      1.573       1.2     -33    26
# Comp:  2           [NII]6583_d      7.180       1.2     -33    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7         1
#  comp.  1:       -24        39
#  comp.  2:       -28        12
# chi2/DOF: 0.5858; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.292      0.99     -24    39
# Comp:  1                 Hbeta      6.460      0.99     -24    39
# Comp:  1                Halpha      23.85      0.99     -24    39
# Comp:  2             [SII]6716      8.026      0.92     -28    12
# Comp:  2             [SII]6731      4.136      0.92     -28    12
# Comp:  2              HeII4687      0.000      0.92     -28    12
# Comp:  2               HeI5876      1.349      0.92     -28    12
# Comp:  2          [OIII]5007_d      6.474       1.2     -28    12
# Comp:  2            [OI]6300_d      1.026       1.2     -28    12
# Comp:  2           [NII]6583_d      7.041       1.2     -28    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:       -25        32
#  comp.  2:       -33         8
# chi2/DOF: 0.5824; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.120      0.97     -25    32
# Comp:  1                 Hbeta      7.235      0.97     -25    32
# Comp:  1                Halpha      23.92      0.97     -25    32
# Comp:  2             [SII]6716      7.443      0.92     -33     8
# Comp:  2             [SII]6731      4.306      0.92     -33     8
# Comp:  2              HeII4687      0.000      0.92     -33     8
# Comp:  2               HeI5876      1.180      0.92     -33     8
# Comp:  2          [OIII]5007_d      6.010       1.2     -33     8
# Comp:  2            [OI]6300_d      1.091       1.2     -33     8
# Comp:  2           [NII]6583_d      6.553       1.2     -33     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -25        37
#  comp.  2:       -32        15
# chi2/DOF: 0.5864; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.663      0.98     -25    37
# Comp:  1                 Hbeta      6.685      0.98     -25    37
# Comp:  1                Halpha      23.57      0.98     -25    37
# Comp:  2             [SII]6716      7.508      0.93     -32    15
# Comp:  2             [SII]6731      4.575      0.93     -32    15
# Comp:  2              HeII4687     0.5130      0.93     -32    15
# Comp:  2               HeI5876      1.411      0.93     -32    15
# Comp:  2          [OIII]5007_d      6.232       1.2     -32    15
# Comp:  2            [OI]6300_d      1.711       1.2     -32    15
# Comp:  2           [NII]6583_d      7.101       1.2     -32    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -26        35
#  comp.  2:       -32        30
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.021      0.97     -26    35
# Comp:  1                 Hbeta      5.871      0.97     -26    35
# Comp:  1                Halpha      23.62      0.97     -26    35
# Comp:  2             [SII]6716      7.725      0.96     -32    30
# Comp:  2             [SII]6731      4.470      0.96     -32    30
# Comp:  2              HeII4687     0.1100      0.96     -32    30
# Comp:  2               HeI5876      1.313      0.96     -32    30
# Comp:  2          [OIII]5007_d      6.527       1.2     -32    30
# Comp:  2            [OI]6300_d      1.626       1.2     -32    30
# Comp:  2           [NII]6583_d      7.074       1.2     -32    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        37
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5850; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.057      0.97     -25    33
# Comp:  1                 Hbeta      6.335      0.97     -25    33
# Comp:  1                Halpha      23.81      0.97     -25    33
# Comp:  2             [SII]6716      7.965      0.93     -31    16
# Comp:  2             [SII]6731      4.225      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.255      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.485       1.2     -31    16
# Comp:  2            [OI]6300_d      1.227       1.2     -31    16
# Comp:  2           [NII]6583_d      7.067       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        79
#  comp.  1:       -25        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5846; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.566      0.97     -25    33
# Comp:  1                 Hbeta      5.764      0.97     -25    33
# Comp:  1                Halpha      23.85      0.97     -25    33
# Comp:  2             [SII]6716      7.853      0.93     -31    17
# Comp:  2             [SII]6731      4.137      0.93     -31    17
# Comp:  2              HeII4687      0.000      0.93     -31    17
# Comp:  2               HeI5876      1.309      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.161       1.2     -31    17
# Comp:  2            [OI]6300_d      1.773       1.2     -31    17
# Comp:  2           [NII]6583_d      6.725       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:       -26        31
#  comp.  2:       -29         9
# chi2/DOF: 0.5867; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.786      0.96     -26    31
# Comp:  1                 Hbeta      6.183      0.96     -26    31
# Comp:  1                Halpha      23.54      0.96     -26    31
# Comp:  2             [SII]6716      7.565      0.92     -29     9
# Comp:  2             [SII]6731      4.063      0.92     -29     9
# Comp:  2              HeII4687      0.000      0.92     -29     9
# Comp:  2               HeI5876      1.382      0.92     -29     9
# Comp:  2          [OIII]5007_d      7.179       1.2     -29     9
# Comp:  2            [OI]6300_d      1.682       1.2     -29     9
# Comp:  2           [NII]6583_d      6.668       1.2     -29     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:       -25        31
#  comp.  2:       -31        29
# chi2/DOF: 0.5830; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.457      0.96     -25    31
# Comp:  1                 Hbeta      5.983      0.96     -25    31
# Comp:  1                Halpha      23.50      0.96     -25    31
# Comp:  2             [SII]6716      8.074      0.96     -31    29
# Comp:  2             [SII]6731      4.789      0.96     -31    29
# Comp:  2              HeII4687      0.000      0.96     -31    29
# Comp:  2               HeI5876      1.647      0.96     -31    29
# Comp:  2          [OIII]5007_d      5.758       1.2     -31    29
# Comp:  2            [OI]6300_d      1.472       1.2     -31    29
# Comp:  2           [NII]6583_d      7.293       1.2     -31    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:       -25        29
#  comp.  2:       -29        21
# chi2/DOF: 0.5854; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.902      0.96     -25    29
# Comp:  1                 Hbeta      6.525      0.96     -25    29
# Comp:  1                Halpha      23.29      0.96     -25    29
# Comp:  2             [SII]6716      7.710      0.94     -29    21
# Comp:  2             [SII]6731      4.086      0.94     -29    21
# Comp:  2              HeII4687      0.000      0.94     -29    21
# Comp:  2               HeI5876      1.605      0.94     -29    21
# Comp:  2          [OIII]5007_d      7.224       1.2     -29    21
# Comp:  2            [OI]6300_d      1.884       1.2     -29    21
# Comp:  2           [NII]6583_d      6.724       1.2     -29    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -26        34
#  comp.  2:       -34        20
# chi2/DOF: 0.5839; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.535      0.97     -26    34
# Comp:  1                 Hbeta      6.308      0.97     -26    34
# Comp:  1                Halpha      23.66      0.97     -26    34
# Comp:  2             [SII]6716      8.032      0.94     -34    20
# Comp:  2             [SII]6731      4.282      0.94     -34    20
# Comp:  2              HeII4687     0.1049      0.94     -34    20
# Comp:  2               HeI5876      1.569      0.94     -34    20
# Comp:  2          [OIII]5007_d      5.958       1.2     -34    20
# Comp:  2            [OI]6300_d      1.053       1.2     -34    20
# Comp:  2           [NII]6583_d      6.821       1.2     -34    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:       -26        33
#  comp.  2:       -33        17
# chi2/DOF: 0.5855; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.963      0.97     -26    33
# Comp:  1                 Hbeta      5.830      0.97     -26    33
# Comp:  1                Halpha      23.86      0.97     -26    33
# Comp:  2             [SII]6716      7.684      0.93     -33    17
# Comp:  2             [SII]6731      4.684      0.93     -33    17
# Comp:  2              HeII4687     0.1424      0.93     -33    17
# Comp:  2               HeI5876      1.348      0.93     -33    17
# Comp:  2          [OIII]5007_d      6.478       1.2     -33    17
# Comp:  2            [OI]6300_d      1.265       1.2     -33    17
# Comp:  2           [NII]6583_d      6.591       1.2     -33    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:       -25        34
#  comp.  2:       -33        21
# chi2/DOF: 0.5837; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.898      0.97     -25    34
# Comp:  1                 Hbeta      6.255      0.97     -25    34
# Comp:  1                Halpha      23.81      0.97     -25    34
# Comp:  2             [SII]6716      7.731      0.94     -33    21
# Comp:  2             [SII]6731      4.906      0.94     -33    21
# Comp:  2              HeII4687     0.3409      0.94     -33    21
# Comp:  2               HeI5876      1.332      0.94     -33    21
# Comp:  2          [OIII]5007_d      6.580       1.2     -33    21
# Comp:  2            [OI]6300_d      1.067       1.2     -33    21
# Comp:  2           [NII]6583_d      6.717       1.2     -33    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:       -24        38
#  comp.  2:       -29         1
# chi2/DOF: 0.5835; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -26        33
#  comp.  2:       -30         1
# chi2/DOF: 0.5838; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.498      0.97     -26    33
# Comp:  1                 Hbeta      6.441      0.97     -26    33
# Comp:  1                Halpha      23.44      0.97     -26    33
# Comp:  2             [SII]6716      7.544      0.92     -30     1
# Comp:  2             [SII]6731      3.934      0.92     -30     1
# Comp:  2              HeII4687      0.000      0.92     -30     1
# Comp:  2               HeI5876      1.330      0.92     -30     1
# Comp:  2          [OIII]5007_d      5.824       1.2     -30     1
# Comp:  2            [OI]6300_d      1.291       1.2     -30     1
# Comp:  2           [NII]6583_d      6.709       1.2     -30     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8         1
#  comp.  1:       -25        33
#  comp.  2:       -31        16
# chi2/DOF: 0.5860; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 13; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.066      0.97     -25    33
# Comp:  1                 Hbeta      6.562      0.97     -25    33
# Comp:  1                Halpha      23.89      0.97     -25    33
# Comp:  2             [SII]6716      7.668      0.93     -31    16
# Comp:  2             [SII]6731      4.730      0.93     -31    16
# Comp:  2              HeII4687      0.000      0.93     -31    16
# Comp:  2               HeI5876      1.279      0.93     -31    16
# Comp:  2          [OIII]5007_d      6.630       1.2     -31    16
# Comp:  2            [OI]6300_d      1.755       1.2     -31    16
# Comp:  2           [NII]6583_d      6.859       1.2     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:       -25        31
#  comp.  2:       -33         1
# chi2/DOF: 0.5860; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.129      0.96     -25    31
# Comp:  1                 Hbeta      6.108      0.96     -25    31
# Comp:  1                Halpha      23.43      0.96     -25    31
# Comp:  2             [SII]6716      7.647      0.92     -33     1
# Comp:  2             [SII]6731      4.735      0.92     -33     1
# Comp:  2              HeII4687    0.01924      0.92     -33     1
# Comp:  2               HeI5876      1.225      0.92     -33     1
# Comp:  2          [OIII]5007_d      6.473       1.2     -33     1
# Comp:  2            [OI]6300_d      1.558       1.2     -33     1
# Comp:  2           [NII]6583_d      7.047       1.2     -33     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        34
#  comp.  1:       -25        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5850; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.201      0.97     -25    33
# Comp:  1                 Hbeta      6.091      0.97     -25    33
# Comp:  1                Halpha      23.52      0.97     -25    33
# Comp:  2             [SII]6716      7.476      0.93     -31    17
# Comp:  2             [SII]6731      4.413      0.93     -31    17
# Comp:  2              HeII4687      0.000      0.93     -31    17
# Comp:  2               HeI5876      1.102      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.904       1.2     -31    17
# Comp:  2            [OI]6300_d      1.640       1.2     -31    17
# Comp:  2           [NII]6583_d      6.995       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7         1
#  comp.  1:       -26        30
#  comp.  2:       -29        13
# chi2/DOF: 0.5829; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.802      0.96     -26    30
# Comp:  1                 Hbeta      6.376      0.96     -26    30
# Comp:  1                Halpha      23.51      0.96     -26    30
# Comp:  2             [SII]6716      7.637      0.92     -29    13
# Comp:  2             [SII]6731      4.347      0.92     -29    13
# Comp:  2              HeII4687      0.000      0.92     -29    13
# Comp:  2               HeI5876      1.330      0.92     -29    13
# Comp:  2          [OIII]5007_d      5.888       1.2     -29    13
# Comp:  2            [OI]6300_d      1.646       1.2     -29    13
# Comp:  2           [NII]6583_d      6.884       1.2     -29    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13       119
#  comp.  1:       -25        31
#  comp.  2:       -31        17
# chi2/DOF: 0.5839; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.013      0.96     -25    31
# Comp:  1                 Hbeta      5.394      0.96     -25    31
# Comp:  1                Halpha      23.23      0.96     -25    31
# Comp:  2             [SII]6716      7.393      0.93     -31    17
# Comp:  2             [SII]6731      4.760      0.93     -31    17
# Comp:  2              HeII4687     0.2217      0.93     -31    17
# Comp:  2               HeI5876      1.322      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.320       1.2     -31    17
# Comp:  2            [OI]6300_d      1.953       1.2     -31    17
# Comp:  2           [NII]6583_d      6.947       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12         1
#  comp.  1:       -25        37
#  comp.  2:       -29        23
# chi2/DOF: 0.5833; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.893      0.98     -25    37
# Comp:  1                 Hbeta      6.617      0.98     -25    37
# Comp:  1                Halpha      24.24      0.98     -25    37
# Comp:  2             [SII]6716      7.845      0.94     -29    23
# Comp:  2             [SII]6731      4.145      0.94     -29    23
# Comp:  2              HeII4687      0.000      0.94     -29    23
# Comp:  2               HeI5876      1.206      0.94     -29    23
# Comp:  2          [OIII]5007_d      6.393       1.2     -29    23
# Comp:  2            [OI]6300_d      1.845       1.2     -29    23
# Comp:  2           [NII]6583_d      6.907       1.2     -29    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -27        33
#  comp.  2:       -28        24
# chi2/DOF: 0.5820; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.376      0.97     -27    33
# Comp:  1                 Hbeta      5.340      0.97     -27    33
# Comp:  1                Halpha      23.50      0.97     -27    33
# Comp:  2             [SII]6716      7.925      0.94     -28    24
# Comp:  2             [SII]6731      4.164      0.94     -28    24
# Comp:  2              HeII4687    0.05235      0.94     -28    24
# Comp:  2               HeI5876      1.287      0.94     -28    24
# Comp:  2          [OIII]5007_d      6.538       1.2     -28    24
# Comp:  2            [OI]6300_d      1.400       1.2     -28    24
# Comp:  2           [NII]6583_d      6.694       1.2     -28    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:       -26        32
#  comp.  2:       -30         1
# chi2/DOF: 0.5860; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.742      0.96     -26    32
# Comp:  1                 Hbeta      6.061      0.96     -26    32
# Comp:  1                Halpha      23.20      0.96     -26    32
# Comp:  2             [SII]6716      7.423      0.92     -30     1
# Comp:  2             [SII]6731      4.096      0.92     -30     1
# Comp:  2              HeII4687     0.4846      0.92     -30     1
# Comp:  2               HeI5876      1.306      0.92     -30     1
# Comp:  2          [OIII]5007_d      6.826       1.2     -30     1
# Comp:  2            [OI]6300_d      1.239       1.2     -30     1
# Comp:  2           [NII]6583_d      6.514       1.2     -30     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         1
#  comp.  1:       -24        34
#  comp.  2:       -30         6
# chi2/DOF: 0.5841; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.163      0.97     -24    34
# Comp:  1                 Hbeta      6.222      0.97     -24    34
# Comp:  1                Halpha      23.56      0.97     -24    34
# Comp:  2             [SII]6716      7.388      0.92     -30     6
# Comp:  2             [SII]6731      4.731      0.92     -30     6
# Comp:  2              HeII4687     0.5262      0.92     -30     6
# Comp:  2               HeI5876      1.352      0.92     -30     6
# Comp:  2          [OIII]5007_d      6.277       1.2     -30     6
# Comp:  2            [OI]6300_d      1.143       1.2     -30     6
# Comp:  2           [NII]6583_d      6.752       1.2     -30     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         1
#  comp.  1:       -25        33
#  comp.  2:       -35        21
# chi2/DOF: 0.5865; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.086      0.97     -25    33
# Comp:  1                 Hbeta      6.055      0.97     -25    33
# Comp:  1                Halpha      23.67      0.97     -25    33
# Comp:  2             [SII]6716      7.501      0.94     -35    21
# Comp:  2             [SII]6731      4.713      0.94     -35    21
# Comp:  2              HeII4687      0.000      0.94     -35    21
# Comp:  2               HeI5876      1.266      0.94     -35    21
# Comp:  2          [OIII]5007_d      6.404       1.2     -35    21
# Comp:  2            [OI]6300_d      1.709       1.2     -35    21
# Comp:  2           [NII]6583_d      7.018       1.2     -35    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        23
#  comp.  1:       -25        33
#  comp.  2:       -31        17
# chi2/DOF: 0.5869; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.611      0.97     -25    33
# Comp:  1                 Hbeta      6.247      0.97     -25    33
# Comp:  1                Halpha      23.64      0.97     -25    33
# Comp:  2             [SII]6716      7.576      0.93     -31    17
# Comp:  2             [SII]6731      4.698      0.93     -31    17
# Comp:  2              HeII4687      0.000      0.93     -31    17
# Comp:  2               HeI5876      1.092      0.93     -31    17
# Comp:  2          [OIII]5007_d      6.265       1.2     -31    17
# Comp:  2            [OI]6300_d      1.005       1.2     -31    17
# Comp:  2           [NII]6583_d      6.834       1.2     -31    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7       126
#  comp.  1:       -26        35
#  comp.  2:       -32        13
# chi2/DOF: 0.5854; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.680      0.97     -26    35
# Comp:  1                 Hbeta      6.643      0.97     -26    35
# Comp:  1                Halpha      23.48      0.97     -26    35
# Comp:  2             [SII]6716      7.667      0.92     -32    13
# Comp:  2             [SII]6731      4.253      0.92     -32    13
# Comp:  2              HeII4687      0.000      0.92     -32    13
# Comp:  2               HeI5876      1.229      0.92     -32    13
# Comp:  2          [OIII]5007_d      6.317       1.2     -32    13
# Comp:  2            [OI]6300_d     0.8944       1.2     -32    13
# Comp:  2           [NII]6583_d      7.118       1.2     -32    13
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.51744504, 0.49338543, 0.4647494 , 0.38565855, 0.37350515,
#        0.18837283, 0.16722214, 0.3919892 , 0.42242353, 0.36560281])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.73597062,  6.18643613, 32.22703382, 10.70579957,  6.226409  ,
#         0.        ,  1.60166868,  6.7010014 ,  1.93308932,  9.50674254])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_5_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_5_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_5_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_5_noreg_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.088443    0.012250
# 1         Hbeta  0.146454    0.011680
# 2        Halpha  0.762926    0.011002
# 3     [SII]6716  0.253443    0.009130
# 4     [SII]6731  0.147401    0.008842
# 5      HeII4687  0.000000    0.004459
# 6       HeI5876  0.037917    0.003959
# 7  [OIII]5007_d  0.158636    0.009280
# 8    [OI]6300_d  0.045763    0.010000
# 9   [NII]6583_d  0.225058    0.008655
#           Name      Flux  Error_flux
# 0       Hgamma  0.088443    0.012250
# 1        Hbeta  0.146454    0.011680
# 2       Halpha  0.762926    0.011002
# 3    [SII]6716  0.253443    0.009130
# 4    [SII]6731  0.147401    0.008842
# 5     HeII4687  0.000000    0.004459
# 6      HeI5876  0.037917    0.003959
# 7   [OIII]4959  0.039659    0.009280
# 8   [OIII]5007  0.118977    0.009280
# 9     [OI]6300  0.034322    0.010000
# 10    [OI]6364  0.011441    0.010000
# 11   [NII]6548  0.056264    0.008655
# 12   [NII]6583  0.168793    0.008655

# %%
np.median(flux_rf_rebin)
# Out:
# 0.023673471920270667
