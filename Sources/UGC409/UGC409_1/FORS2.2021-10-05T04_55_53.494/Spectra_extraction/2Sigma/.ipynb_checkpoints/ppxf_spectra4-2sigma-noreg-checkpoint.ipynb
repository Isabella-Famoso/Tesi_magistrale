# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/Spectra_extraction/redshift.txt")    
z = red[3][0] 
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11386358 2.11459101 2.11531845 ... 3.4865375  3.48726493 3.48799237]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3336, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143462565

# %%
stars_templates.shape
# Out:
# (3336, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3336, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         4
# chi2/DOF: 0.01180; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
# chi2/DOF: 0.004110; DOF: 2017; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.10742132 1.049776   0.94278636 ... 1.4083164  1.39609055 1.34228977]
# [0.85237946 0.89449008 0.91670028 ... 1.3847482  1.38386832 1.37688919]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-26.93787286,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         5
#  comp.  1:       -32        29
#  comp.  2:       -34        35
# chi2/DOF: 0.5469; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.347      0.30     -32    29
# Comp:  1                 Hbeta      5.946      0.30     -32    29
# Comp:  1                Halpha      18.78      0.30     -32    29
# Comp:  2             [SII]6716      5.003      0.31     -34    35
# Comp:  2             [SII]6731      3.532      0.31     -34    35
# Comp:  2              HeII4687      0.000      0.31     -34    35
# Comp:  2               HeI5876     0.3449      0.31     -34    35
# Comp:  2          [OIII]5007_d      5.601      0.39     -34    35
# Comp:  2            [OI]6300_d     0.9125      0.39     -34    35
# Comp:  2           [NII]6583_d      6.552      0.39     -34    35
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  11.89; gas flux:      2 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  28.86; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  94.05; gas flux:     26 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  24.43; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  16.64; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.673; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  20.01; gas flux:      6 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.155; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  23.79; gas flux:      9 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -32        31
#  comp.  2:       -36        33
# chi2/DOF: 0.5441; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.423      0.30     -32    31
# Comp:  1                 Hbeta      5.988      0.30     -32    31
# Comp:  1                Halpha      18.93      0.30     -32    31
# Comp:  2             [SII]6716      5.075      0.31     -36    33
# Comp:  2             [SII]6731      3.338      0.31     -36    33
# Comp:  2              HeII4687      0.000      0.31     -36    33
# Comp:  2               HeI5876     0.2809      0.31     -36    33
# Comp:  2          [OIII]5007_d      5.610      0.39     -36    33
# Comp:  2            [OI]6300_d     0.9975      0.39     -36    33
# Comp:  2           [NII]6583_d      6.466      0.39     -36    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -32        26
#  comp.  2:       -38        36
# chi2/DOF: 0.5412; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.398      0.30     -32    26
# Comp:  1                 Hbeta      5.981      0.30     -32    26
# Comp:  1                Halpha      18.40      0.30     -32    26
# Comp:  2             [SII]6716      5.205      0.31     -38    36
# Comp:  2             [SII]6731      3.448      0.31     -38    36
# Comp:  2              HeII4687      0.000      0.31     -38    36
# Comp:  2               HeI5876     0.1456      0.31     -38    36
# Comp:  2          [OIII]5007_d      5.224      0.39     -38    36
# Comp:  2            [OI]6300_d     0.7811      0.39     -38    36
# Comp:  2           [NII]6583_d      6.582      0.39     -38    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -32        26
#  comp.  2:       -32        29
# chi2/DOF: 0.5435; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.251      0.30     -32    26
# Comp:  1                 Hbeta      6.163      0.30     -32    26
# Comp:  1                Halpha      18.86      0.30     -32    26
# Comp:  2             [SII]6716      4.825      0.30     -32    29
# Comp:  2             [SII]6731      3.480      0.30     -32    29
# Comp:  2              HeII4687      0.000      0.30     -32    29
# Comp:  2               HeI5876     0.3308      0.30     -32    29
# Comp:  2          [OIII]5007_d      5.531      0.38     -32    29
# Comp:  2            [OI]6300_d      1.089      0.38     -32    29
# Comp:  2           [NII]6583_d      6.436      0.38     -32    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        18
#  comp.  1:       -33        30
#  comp.  2:       -36        30
# chi2/DOF: 0.5414; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.755      0.30     -33    30
# Comp:  1                 Hbeta      5.806      0.30     -33    30
# Comp:  1                Halpha      19.07      0.30     -33    30
# Comp:  2             [SII]6716      4.886      0.30     -36    30
# Comp:  2             [SII]6731      3.587      0.30     -36    30
# Comp:  2              HeII4687     0.3173      0.30     -36    30
# Comp:  2               HeI5876     0.2889      0.30     -36    30
# Comp:  2          [OIII]5007_d      5.544      0.38     -36    30
# Comp:  2            [OI]6300_d      1.116      0.38     -36    30
# Comp:  2           [NII]6583_d      6.447      0.38     -36    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        53
#  comp.  1:       -31        33
#  comp.  2:       -31        32
# chi2/DOF: 0.5407; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.544      0.31     -31    33
# Comp:  1                 Hbeta      5.598      0.31     -31    33
# Comp:  1                Halpha      19.24      0.31     -31    33
# Comp:  2             [SII]6716      5.000      0.30     -31    32
# Comp:  2             [SII]6731      3.462      0.30     -31    32
# Comp:  2              HeII4687      0.000      0.30     -31    32
# Comp:  2               HeI5876     0.2197      0.30     -31    32
# Comp:  2          [OIII]5007_d      5.288      0.38     -31    32
# Comp:  2            [OI]6300_d     0.9172      0.38     -31    32
# Comp:  2           [NII]6583_d      6.451      0.38     -31    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -32        26
#  comp.  2:       -32        35
# chi2/DOF: 0.5419; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.504      0.30     -32    26
# Comp:  1                 Hbeta      6.379      0.30     -32    26
# Comp:  1                Halpha      18.62      0.30     -32    26
# Comp:  2             [SII]6716      5.030      0.31     -32    35
# Comp:  2             [SII]6731      3.465      0.31     -32    35
# Comp:  2              HeII4687      0.000      0.31     -32    35
# Comp:  2               HeI5876     0.1252      0.31     -32    35
# Comp:  2          [OIII]5007_d      5.220      0.39     -32    35
# Comp:  2            [OI]6300_d     0.8195      0.39     -32    35
# Comp:  2           [NII]6583_d      6.517      0.39     -32    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -33        28
#  comp.  2:       -34        29
# chi2/DOF: 0.5438; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.695      0.30     -33    28
# Comp:  1                 Hbeta      6.004      0.30     -33    28
# Comp:  1                Halpha      18.81      0.30     -33    28
# Comp:  2             [SII]6716      4.843      0.30     -34    29
# Comp:  2             [SII]6731      3.282      0.30     -34    29
# Comp:  2              HeII4687      0.000      0.30     -34    29
# Comp:  2               HeI5876     0.4413      0.30     -34    29
# Comp:  2          [OIII]5007_d      5.655      0.38     -34    29
# Comp:  2            [OI]6300_d     0.8481      0.38     -34    29
# Comp:  2           [NII]6583_d      6.432      0.38     -34    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -33        30
#  comp.  2:       -34        36
# chi2/DOF: 0.5432; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.584      0.30     -33    30
# Comp:  1                 Hbeta      6.440      0.30     -33    30
# Comp:  1                Halpha      19.05      0.30     -33    30
# Comp:  2             [SII]6716      5.195      0.31     -34    36
# Comp:  2             [SII]6731      3.455      0.31     -34    36
# Comp:  2              HeII4687    0.03557      0.31     -34    36
# Comp:  2               HeI5876     0.4360      0.31     -34    36
# Comp:  2          [OIII]5007_d      5.406      0.39     -34    36
# Comp:  2            [OI]6300_d     0.8750      0.39     -34    36
# Comp:  2           [NII]6583_d      6.609      0.39     -34    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        23
#  comp.  1:       -34        26
#  comp.  2:       -35        33
# chi2/DOF: 0.5419; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.406      0.30     -34    26
# Comp:  1                 Hbeta      5.976      0.30     -34    26
# Comp:  1                Halpha      18.87      0.30     -34    26
# Comp:  2             [SII]6716      4.984      0.31     -35    33
# Comp:  2             [SII]6731      3.437      0.31     -35    33
# Comp:  2              HeII4687    0.03265      0.31     -35    33
# Comp:  2               HeI5876     0.4146      0.31     -35    33
# Comp:  2          [OIII]5007_d      5.742      0.39     -35    33
# Comp:  2            [OI]6300_d     0.8892      0.39     -35    33
# Comp:  2           [NII]6583_d      6.521      0.39     -35    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -31        28
#  comp.  2:       -37        37
# chi2/DOF: 0.5433; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.251      0.30     -31    28
# Comp:  1                 Hbeta      6.016      0.30     -31    28
# Comp:  1                Halpha      18.68      0.30     -31    28
# Comp:  2             [SII]6716      5.103      0.31     -37    37
# Comp:  2             [SII]6731      3.624      0.31     -37    37
# Comp:  2              HeII4687    0.04631      0.31     -37    37
# Comp:  2               HeI5876     0.2559      0.31     -37    37
# Comp:  2          [OIII]5007_d      5.829      0.39     -37    37
# Comp:  2            [OI]6300_d     0.8681      0.39     -37    37
# Comp:  2           [NII]6583_d      6.698      0.39     -37    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        33
#  comp.  1:       -35        25
#  comp.  2:       -35        40
# chi2/DOF: 0.5417; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.473      0.30     -35    25
# Comp:  1                 Hbeta      5.796      0.30     -35    25
# Comp:  1                Halpha      18.76      0.30     -35    25
# Comp:  2             [SII]6716      5.298      0.31     -35    40
# Comp:  2             [SII]6731      3.460      0.31     -35    40
# Comp:  2              HeII4687      0.000      0.31     -35    40
# Comp:  2               HeI5876     0.4061      0.31     -35    40
# Comp:  2          [OIII]5007_d      5.739      0.39     -35    40
# Comp:  2            [OI]6300_d     0.9183      0.39     -35    40
# Comp:  2           [NII]6583_d      6.740      0.39     -35    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -36        24
#  comp.  2:       -36        35
# chi2/DOF: 0.5417; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.580      0.30     -36    24
# Comp:  1                 Hbeta      6.014      0.30     -36    24
# Comp:  1                Halpha      18.69      0.30     -36    24
# Comp:  2             [SII]6716      5.152      0.31     -36    35
# Comp:  2             [SII]6731      3.578      0.31     -36    35
# Comp:  2              HeII4687      0.000      0.31     -36    35
# Comp:  2               HeI5876     0.3910      0.31     -36    35
# Comp:  2          [OIII]5007_d      6.137      0.39     -36    35
# Comp:  2            [OI]6300_d      1.068      0.39     -36    35
# Comp:  2           [NII]6583_d      6.582      0.39     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -30        35
#  comp.  2:       -33        33
# chi2/DOF: 0.5404; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.585      0.31     -30    35
# Comp:  1                 Hbeta      6.374      0.31     -30    35
# Comp:  1                Halpha      19.24      0.31     -30    35
# Comp:  2             [SII]6716      4.759      0.31     -33    33
# Comp:  2             [SII]6731      3.479      0.31     -33    33
# Comp:  2              HeII4687      0.000      0.31     -33    33
# Comp:  2               HeI5876     0.2736      0.31     -33    33
# Comp:  2          [OIII]5007_d      5.044      0.39     -33    33
# Comp:  2            [OI]6300_d     0.8625      0.39     -33    33
# Comp:  2           [NII]6583_d      6.498      0.39     -33    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -34        27
#  comp.  2:       -36        38
# chi2/DOF: 0.5426; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.655      0.30     -34    27
# Comp:  1                 Hbeta      6.072      0.30     -34    27
# Comp:  1                Halpha      18.93      0.30     -34    27
# Comp:  2             [SII]6716      5.108      0.31     -36    38
# Comp:  2             [SII]6731      3.535      0.31     -36    38
# Comp:  2              HeII4687    0.01502      0.31     -36    38
# Comp:  2               HeI5876     0.4964      0.31     -36    38
# Comp:  2          [OIII]5007_d      6.020      0.39     -36    38
# Comp:  2            [OI]6300_d     0.9339      0.39     -36    38
# Comp:  2           [NII]6583_d      6.641      0.39     -36    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -33        29
#  comp.  2:       -34        23
# chi2/DOF: 0.5428; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.733      0.30     -33    29
# Comp:  1                 Hbeta      6.180      0.30     -33    29
# Comp:  1                Halpha      18.86      0.30     -33    29
# Comp:  2             [SII]6716      4.777      0.30     -34    23
# Comp:  2             [SII]6731      3.357      0.30     -34    23
# Comp:  2              HeII4687      0.000      0.30     -34    23
# Comp:  2               HeI5876     0.3837      0.30     -34    23
# Comp:  2          [OIII]5007_d      5.559      0.38     -34    23
# Comp:  2            [OI]6300_d     0.8035      0.38     -34    23
# Comp:  2           [NII]6583_d      6.433      0.38     -34    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        43
#  comp.  1:       -33        25
#  comp.  2:       -37        34
# chi2/DOF: 0.5434; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.331      0.30     -33    25
# Comp:  1                 Hbeta      6.031      0.30     -33    25
# Comp:  1                Halpha      18.59      0.30     -33    25
# Comp:  2             [SII]6716      5.111      0.31     -37    34
# Comp:  2             [SII]6731      3.536      0.31     -37    34
# Comp:  2              HeII4687    0.04930      0.31     -37    34
# Comp:  2               HeI5876     0.1685      0.31     -37    34
# Comp:  2          [OIII]5007_d      5.844      0.39     -37    34
# Comp:  2            [OI]6300_d      1.015      0.39     -37    34
# Comp:  2           [NII]6583_d      6.530      0.39     -37    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         7
#  comp.  1:       -33        32
#  comp.  2:       -35        30
# chi2/DOF: 0.5428; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.253      0.30     -33    32
# Comp:  1                 Hbeta      6.646      0.30     -33    32
# Comp:  1                Halpha      19.19      0.30     -33    32
# Comp:  2             [SII]6716      5.064      0.30     -35    30
# Comp:  2             [SII]6731      3.524      0.30     -35    30
# Comp:  2              HeII4687      0.000      0.30     -35    30
# Comp:  2               HeI5876     0.4307      0.30     -35    30
# Comp:  2          [OIII]5007_d      5.755      0.38     -35    30
# Comp:  2            [OI]6300_d     0.8493      0.38     -35    30
# Comp:  2           [NII]6583_d      6.565      0.38     -35    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        28
#  comp.  1:       -31        34
#  comp.  2:       -35        41
# chi2/DOF: 0.5405; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.473      0.31     -31    34
# Comp:  1                 Hbeta      6.223      0.31     -31    34
# Comp:  1                Halpha      19.27      0.31     -31    34
# Comp:  2             [SII]6716      5.118      0.31     -35    41
# Comp:  2             [SII]6731      3.708      0.31     -35    41
# Comp:  2              HeII4687      0.000      0.31     -35    41
# Comp:  2               HeI5876     0.3675      0.31     -35    41
# Comp:  2          [OIII]5007_d      5.872      0.40     -35    41
# Comp:  2            [OI]6300_d      1.005      0.40     -35    41
# Comp:  2           [NII]6583_d      6.775      0.40     -35    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -32        30
#  comp.  2:       -33        29
# chi2/DOF: 0.5409; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.535      0.30     -32    30
# Comp:  1                 Hbeta      6.471      0.30     -32    30
# Comp:  1                Halpha      18.85      0.30     -32    30
# Comp:  2             [SII]6716      4.741      0.30     -33    29
# Comp:  2             [SII]6731      3.369      0.30     -33    29
# Comp:  2              HeII4687     0.3147      0.30     -33    29
# Comp:  2               HeI5876     0.3814      0.30     -33    29
# Comp:  2          [OIII]5007_d      5.353      0.38     -33    29
# Comp:  2            [OI]6300_d     0.6366      0.38     -33    29
# Comp:  2           [NII]6583_d      6.354      0.38     -33    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -30        34
#  comp.  2:       -34        33
# chi2/DOF: 0.5412; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.462      0.31     -30    34
# Comp:  1                 Hbeta      6.136      0.31     -30    34
# Comp:  1                Halpha      19.24      0.31     -30    34
# Comp:  2             [SII]6716      4.969      0.31     -34    33
# Comp:  2             [SII]6731      3.619      0.31     -34    33
# Comp:  2              HeII4687      0.000      0.31     -34    33
# Comp:  2               HeI5876     0.3789      0.31     -34    33
# Comp:  2          [OIII]5007_d      6.045      0.39     -34    33
# Comp:  2            [OI]6300_d     0.8454      0.39     -34    33
# Comp:  2           [NII]6583_d      6.503      0.39     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        45
#  comp.  1:       -29        34
#  comp.  2:       -34        35
# chi2/DOF: 0.5409; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.570      0.31     -29    34
# Comp:  1                 Hbeta      6.313      0.31     -29    34
# Comp:  1                Halpha      19.28      0.31     -29    34
# Comp:  2             [SII]6716      5.240      0.31     -34    35
# Comp:  2             [SII]6731      3.494      0.31     -34    35
# Comp:  2              HeII4687      0.000      0.31     -34    35
# Comp:  2               HeI5876     0.4309      0.31     -34    35
# Comp:  2          [OIII]5007_d      5.237      0.39     -34    35
# Comp:  2            [OI]6300_d     0.9162      0.39     -34    35
# Comp:  2           [NII]6583_d      6.552      0.39     -34    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -33        34
#  comp.  2:       -35        36
# chi2/DOF: 0.5429; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.530      0.31     -33    34
# Comp:  1                 Hbeta      6.342      0.31     -33    34
# Comp:  1                Halpha      19.16      0.31     -33    34
# Comp:  2             [SII]6716      5.199      0.31     -35    36
# Comp:  2             [SII]6731      3.699      0.31     -35    36
# Comp:  2              HeII4687      0.000      0.31     -35    36
# Comp:  2               HeI5876     0.2845      0.31     -35    36
# Comp:  2          [OIII]5007_d      5.390      0.39     -35    36
# Comp:  2            [OI]6300_d     0.9153      0.39     -35    36
# Comp:  2           [NII]6583_d      6.721      0.39     -35    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -33        25
#  comp.  2:       -36        35
# chi2/DOF: 0.5419; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.387      0.30     -33    25
# Comp:  1                 Hbeta      5.453      0.30     -33    25
# Comp:  1                Halpha      18.44      0.30     -33    25
# Comp:  2             [SII]6716      5.189      0.31     -36    35
# Comp:  2             [SII]6731      3.527      0.31     -36    35
# Comp:  2              HeII4687      0.000      0.31     -36    35
# Comp:  2               HeI5876     0.3484      0.31     -36    35
# Comp:  2          [OIII]5007_d      5.889      0.39     -36    35
# Comp:  2            [OI]6300_d      1.070      0.39     -36    35
# Comp:  2           [NII]6583_d      6.598      0.39     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -35        24
#  comp.  2:       -33        28
# chi2/DOF: 0.5421; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.416      0.30     -35    24
# Comp:  1                 Hbeta      5.784      0.30     -35    24
# Comp:  1                Halpha      18.66      0.30     -35    24
# Comp:  2             [SII]6716      4.875      0.30     -33    28
# Comp:  2             [SII]6731      3.598      0.30     -33    28
# Comp:  2              HeII4687    0.03291      0.30     -33    28
# Comp:  2               HeI5876     0.3841      0.30     -33    28
# Comp:  2          [OIII]5007_d      5.279      0.38     -33    28
# Comp:  2            [OI]6300_d     0.9393      0.38     -33    28
# Comp:  2           [NII]6583_d      6.288      0.38     -33    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        48
#  comp.  1:       -35        28
#  comp.  2:       -35        33
# chi2/DOF: 0.5410; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.186      0.30     -35    28
# Comp:  1                 Hbeta      5.826      0.30     -35    28
# Comp:  1                Halpha      18.80      0.30     -35    28
# Comp:  2             [SII]6716      4.978      0.31     -35    33
# Comp:  2             [SII]6731      3.545      0.31     -35    33
# Comp:  2              HeII4687    0.03920      0.31     -35    33
# Comp:  2               HeI5876     0.3585      0.31     -35    33
# Comp:  2          [OIII]5007_d      5.238      0.39     -35    33
# Comp:  2            [OI]6300_d     0.7853      0.39     -35    33
# Comp:  2           [NII]6583_d      6.654      0.39     -35    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -32        29
#  comp.  2:       -36        36
# chi2/DOF: 0.5392; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.665      0.30     -32    29
# Comp:  1                 Hbeta      5.578      0.30     -32    29
# Comp:  1                Halpha      18.86      0.30     -32    29
# Comp:  2             [SII]6716      4.748      0.31     -36    36
# Comp:  2             [SII]6731      3.435      0.31     -36    36
# Comp:  2              HeII4687      0.000      0.31     -36    36
# Comp:  2               HeI5876     0.4115      0.31     -36    36
# Comp:  2          [OIII]5007_d      5.492      0.39     -36    36
# Comp:  2            [OI]6300_d     0.8496      0.39     -36    36
# Comp:  2           [NII]6583_d      6.573      0.39     -36    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -33        32
#  comp.  2:       -33        35
# chi2/DOF: 0.5422; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.569      0.30     -33    32
# Comp:  1                 Hbeta      6.343      0.30     -33    32
# Comp:  1                Halpha      18.89      0.30     -33    32
# Comp:  2             [SII]6716      4.843      0.31     -33    35
# Comp:  2             [SII]6731      3.407      0.31     -33    35
# Comp:  2              HeII4687     0.2602      0.31     -33    35
# Comp:  2               HeI5876     0.3005      0.31     -33    35
# Comp:  2          [OIII]5007_d      5.492      0.39     -33    35
# Comp:  2            [OI]6300_d     0.8967      0.39     -33    35
# Comp:  2           [NII]6583_d      6.550      0.39     -33    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -30        35
#  comp.  2:       -33        32
# chi2/DOF: 0.5404; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.493      0.31     -30    35
# Comp:  1                 Hbeta      6.226      0.31     -30    35
# Comp:  1                Halpha      19.03      0.31     -30    35
# Comp:  2             [SII]6716      5.073      0.30     -33    32
# Comp:  2             [SII]6731      3.379      0.30     -33    32
# Comp:  2              HeII4687    0.02777      0.30     -33    32
# Comp:  2               HeI5876     0.2464      0.30     -33    32
# Comp:  2          [OIII]5007_d      6.010      0.38     -33    32
# Comp:  2            [OI]6300_d     0.7000      0.38     -33    32
# Comp:  2           [NII]6583_d      6.530      0.38     -33    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        74
#  comp.  1:       -35        29
#  comp.  2:       -32        34
# chi2/DOF: 0.5402; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.613      0.30     -35    29
# Comp:  1                 Hbeta      6.012      0.30     -35    29
# Comp:  1                Halpha      18.80      0.30     -35    29
# Comp:  2             [SII]6716      4.911      0.31     -32    34
# Comp:  2             [SII]6731      3.388      0.31     -32    34
# Comp:  2              HeII4687      0.000      0.31     -32    34
# Comp:  2               HeI5876     0.4247      0.31     -32    34
# Comp:  2          [OIII]5007_d      5.672      0.39     -32    34
# Comp:  2            [OI]6300_d     0.8479      0.39     -32    34
# Comp:  2           [NII]6583_d      6.583      0.39     -32    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -31        36
#  comp.  2:       -32        34
# chi2/DOF: 0.5403; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.404      0.31     -31    36
# Comp:  1                 Hbeta      6.647      0.31     -31    36
# Comp:  1                Halpha      19.07      0.31     -31    36
# Comp:  2             [SII]6716      4.907      0.31     -32    34
# Comp:  2             [SII]6731      3.495      0.31     -32    34
# Comp:  2              HeII4687     0.2790      0.31     -32    34
# Comp:  2               HeI5876     0.4949      0.31     -32    34
# Comp:  2          [OIII]5007_d      5.798      0.39     -32    34
# Comp:  2            [OI]6300_d      1.080      0.39     -32    34
# Comp:  2           [NII]6583_d      6.459      0.39     -32    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -31        25
#  comp.  2:       -33        38
# chi2/DOF: 0.5437; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.393      0.30     -31    25
# Comp:  1                 Hbeta      6.037      0.30     -31    25
# Comp:  1                Halpha      18.57      0.30     -31    25
# Comp:  2             [SII]6716      4.915      0.31     -33    38
# Comp:  2             [SII]6731      3.574      0.31     -33    38
# Comp:  2              HeII4687      0.000      0.31     -33    38
# Comp:  2               HeI5876     0.3126      0.31     -33    38
# Comp:  2          [OIII]5007_d      5.829      0.39     -33    38
# Comp:  2            [OI]6300_d     0.9425      0.39     -33    38
# Comp:  2           [NII]6583_d      6.648      0.39     -33    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        86
#  comp.  1:       -31        31
#  comp.  2:       -35        37
# chi2/DOF: 0.5424; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.475      0.30     -31    31
# Comp:  1                 Hbeta      6.132      0.30     -31    31
# Comp:  1                Halpha      19.12      0.30     -31    31
# Comp:  2             [SII]6716      5.196      0.31     -35    37
# Comp:  2             [SII]6731      3.421      0.31     -35    37
# Comp:  2              HeII4687      0.000      0.31     -35    37
# Comp:  2               HeI5876     0.5314      0.31     -35    37
# Comp:  2          [OIII]5007_d      5.985      0.39     -35    37
# Comp:  2            [OI]6300_d     0.9207      0.39     -35    37
# Comp:  2           [NII]6583_d      6.703      0.39     -35    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -31        32
#  comp.  2:       -33        37
# chi2/DOF: 0.5434; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.563      0.30     -31    32
# Comp:  1                 Hbeta      6.180      0.30     -31    32
# Comp:  1                Halpha      19.13      0.30     -31    32
# Comp:  2             [SII]6716      5.147      0.31     -33    37
# Comp:  2             [SII]6731      3.392      0.31     -33    37
# Comp:  2              HeII4687   0.001779      0.31     -33    37
# Comp:  2               HeI5876     0.2557      0.31     -33    37
# Comp:  2          [OIII]5007_d      5.727      0.39     -33    37
# Comp:  2            [OI]6300_d      1.114      0.39     -33    37
# Comp:  2           [NII]6583_d      6.604      0.39     -33    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        15
#  comp.  1:       -34        24
#  comp.  2:       -35        40
# chi2/DOF: 0.5421; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.464      0.30     -34    24
# Comp:  1                 Hbeta      6.214      0.30     -34    24
# Comp:  1                Halpha      18.62      0.30     -34    24
# Comp:  2             [SII]6716      5.033      0.31     -35    40
# Comp:  2             [SII]6731      3.451      0.31     -35    40
# Comp:  2              HeII4687      0.000      0.31     -35    40
# Comp:  2               HeI5876     0.3259      0.31     -35    40
# Comp:  2          [OIII]5007_d      5.672      0.39     -35    40
# Comp:  2            [OI]6300_d      1.162      0.39     -35    40
# Comp:  2           [NII]6583_d      6.597      0.39     -35    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        55
#  comp.  1:       -33        24
#  comp.  2:       -34        33
# chi2/DOF: 0.5415; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.617      0.30     -33    24
# Comp:  1                 Hbeta      6.006      0.30     -33    24
# Comp:  1                Halpha      18.46      0.30     -33    24
# Comp:  2             [SII]6716      4.977      0.31     -34    33
# Comp:  2             [SII]6731      3.521      0.31     -34    33
# Comp:  2              HeII4687      0.000      0.31     -34    33
# Comp:  2               HeI5876     0.3824      0.31     -34    33
# Comp:  2          [OIII]5007_d      5.642      0.39     -34    33
# Comp:  2            [OI]6300_d     0.9534      0.39     -34    33
# Comp:  2           [NII]6583_d      6.514      0.39     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -33        22
#  comp.  2:       -34        38
# chi2/DOF: 0.5401; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.679      0.30     -33    22
# Comp:  1                 Hbeta      5.744      0.30     -33    22
# Comp:  1                Halpha      18.43      0.30     -33    22
# Comp:  2             [SII]6716      5.092      0.31     -34    38
# Comp:  2             [SII]6731      3.433      0.31     -34    38
# Comp:  2              HeII4687      0.000      0.31     -34    38
# Comp:  2               HeI5876     0.4673      0.31     -34    38
# Comp:  2          [OIII]5007_d      5.745      0.39     -34    38
# Comp:  2            [OI]6300_d      1.006      0.39     -34    38
# Comp:  2           [NII]6583_d      6.705      0.39     -34    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        35
#  comp.  1:       -32        30
#  comp.  2:       -34        35
# chi2/DOF: 0.5425; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.416      0.30     -32    30
# Comp:  1                 Hbeta      6.221      0.30     -32    30
# Comp:  1                Halpha      18.95      0.30     -32    30
# Comp:  2             [SII]6716      5.269      0.31     -34    35
# Comp:  2             [SII]6731      3.440      0.31     -34    35
# Comp:  2              HeII4687      0.000      0.31     -34    35
# Comp:  2               HeI5876     0.2987      0.31     -34    35
# Comp:  2          [OIII]5007_d      6.054      0.39     -34    35
# Comp:  2            [OI]6300_d     0.7557      0.39     -34    35
# Comp:  2           [NII]6583_d      6.642      0.39     -34    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        11
#  comp.  1:       -32        30
#  comp.  2:       -37        39
# chi2/DOF: 0.5403; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.714      0.30     -32    30
# Comp:  1                 Hbeta      5.694      0.30     -32    30
# Comp:  1                Halpha      19.22      0.30     -32    30
# Comp:  2             [SII]6716      5.098      0.31     -37    39
# Comp:  2             [SII]6731      3.639      0.31     -37    39
# Comp:  2              HeII4687    0.06487      0.31     -37    39
# Comp:  2               HeI5876     0.2761      0.31     -37    39
# Comp:  2          [OIII]5007_d      5.921      0.39     -37    39
# Comp:  2            [OI]6300_d     0.8217      0.39     -37    39
# Comp:  2           [NII]6583_d      6.551      0.39     -37    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -32        30
#  comp.  2:       -35        34
# chi2/DOF: 0.5401; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.624      0.30     -32    30
# Comp:  1                 Hbeta      5.893      0.30     -32    30
# Comp:  1                Halpha      18.85      0.30     -32    30
# Comp:  2             [SII]6716      5.013      0.31     -35    34
# Comp:  2             [SII]6731      3.654      0.31     -35    34
# Comp:  2              HeII4687     0.1589      0.31     -35    34
# Comp:  2               HeI5876     0.4159      0.31     -35    34
# Comp:  2          [OIII]5007_d      5.928      0.39     -35    34
# Comp:  2            [OI]6300_d     0.6776      0.39     -35    34
# Comp:  2           [NII]6583_d      6.465      0.39     -35    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -31        29
#  comp.  2:       -35        30
# chi2/DOF: 0.5429; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -30        29
#  comp.  2:       -33        25
# chi2/DOF: 0.5424; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.371      0.30     -30    29
# Comp:  1                 Hbeta      5.879      0.30     -30    29
# Comp:  1                Halpha      18.90      0.30     -30    29
# Comp:  2             [SII]6716      5.010      0.30     -33    25
# Comp:  2             [SII]6731      3.282      0.30     -33    25
# Comp:  2              HeII4687    0.01107      0.30     -33    25
# Comp:  2               HeI5876     0.4863      0.30     -33    25
# Comp:  2          [OIII]5007_d      5.390      0.38     -33    25
# Comp:  2            [OI]6300_d     0.8264      0.38     -33    25
# Comp:  2           [NII]6583_d      6.290      0.38     -33    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -33        29
#  comp.  2:       -33        38
# chi2/DOF: 0.5417; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.640      0.30     -33    29
# Comp:  1                 Hbeta      6.673      0.30     -33    29
# Comp:  1                Halpha      19.07      0.30     -33    29
# Comp:  2             [SII]6716      4.986      0.31     -33    38
# Comp:  2             [SII]6731      3.677      0.31     -33    38
# Comp:  2              HeII4687      0.000      0.31     -33    38
# Comp:  2               HeI5876     0.3242      0.31     -33    38
# Comp:  2          [OIII]5007_d      5.378      0.39     -33    38
# Comp:  2            [OI]6300_d     0.9890      0.39     -33    38
# Comp:  2           [NII]6583_d      6.646      0.39     -33    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        46
#  comp.  1:       -34        23
#  comp.  2:       -33        31
# chi2/DOF: 0.5409; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.551      0.30     -34    23
# Comp:  1                 Hbeta      5.824      0.30     -34    23
# Comp:  1                Halpha      18.44      0.30     -34    23
# Comp:  2             [SII]6716      5.202      0.30     -33    31
# Comp:  2             [SII]6731      3.660      0.30     -33    31
# Comp:  2              HeII4687      0.000      0.30     -33    31
# Comp:  2               HeI5876     0.3673      0.30     -33    31
# Comp:  2          [OIII]5007_d      5.652      0.38     -33    31
# Comp:  2            [OI]6300_d     0.9893      0.38     -33    31
# Comp:  2           [NII]6583_d      6.584      0.38     -33    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -31        28
#  comp.  2:       -34        38
# chi2/DOF: 0.5420; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.302      0.30     -31    28
# Comp:  1                 Hbeta      6.210      0.30     -31    28
# Comp:  1                Halpha      18.81      0.30     -31    28
# Comp:  2             [SII]6716      4.885      0.31     -34    38
# Comp:  2             [SII]6731      3.501      0.31     -34    38
# Comp:  2              HeII4687      0.000      0.31     -34    38
# Comp:  2               HeI5876     0.4006      0.31     -34    38
# Comp:  2          [OIII]5007_d      6.116      0.39     -34    38
# Comp:  2            [OI]6300_d     0.9277      0.39     -34    38
# Comp:  2           [NII]6583_d      6.614      0.39     -34    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -34        28
#  comp.  2:       -31        33
# chi2/DOF: 0.5407; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.594      0.30     -34    28
# Comp:  1                 Hbeta      6.515      0.30     -34    28
# Comp:  1                Halpha      18.95      0.30     -34    28
# Comp:  2             [SII]6716      4.961      0.31     -31    33
# Comp:  2             [SII]6731      3.509      0.31     -31    33
# Comp:  2              HeII4687      0.000      0.31     -31    33
# Comp:  2               HeI5876     0.4383      0.31     -31    33
# Comp:  2          [OIII]5007_d      5.864      0.39     -31    33
# Comp:  2            [OI]6300_d     0.8744      0.39     -31    33
# Comp:  2           [NII]6583_d      6.509      0.39     -31    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        41
#  comp.  1:       -31        26
#  comp.  2:       -34        37
# chi2/DOF: 0.5420; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.499      0.30     -31    26
# Comp:  1                 Hbeta      5.771      0.30     -31    26
# Comp:  1                Halpha      18.76      0.30     -31    26
# Comp:  2             [SII]6716      4.919      0.31     -34    37
# Comp:  2             [SII]6731      3.657      0.31     -34    37
# Comp:  2              HeII4687    0.04993      0.31     -34    37
# Comp:  2               HeI5876     0.4213      0.31     -34    37
# Comp:  2          [OIII]5007_d      5.072      0.39     -34    37
# Comp:  2            [OI]6300_d      1.130      0.39     -34    37
# Comp:  2           [NII]6583_d      6.684      0.39     -34    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        57
#  comp.  1:       -32        33
#  comp.  2:       -32        39
# chi2/DOF: 0.5434; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.218      0.31     -32    33
# Comp:  1                 Hbeta      6.334      0.31     -32    33
# Comp:  1                Halpha      19.12      0.31     -32    33
# Comp:  2             [SII]6716      5.046      0.31     -32    39
# Comp:  2             [SII]6731      3.486      0.31     -32    39
# Comp:  2              HeII4687      0.000      0.31     -32    39
# Comp:  2               HeI5876     0.3809      0.31     -32    39
# Comp:  2          [OIII]5007_d      5.445      0.39     -32    39
# Comp:  2            [OI]6300_d     0.9654      0.39     -32    39
# Comp:  2           [NII]6583_d      6.644      0.39     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -33        33
#  comp.  2:       -32        37
# chi2/DOF: 0.5447; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.460      0.30     -33    33
# Comp:  1                 Hbeta      5.841      0.30     -33    33
# Comp:  1                Halpha      18.97      0.30     -33    33
# Comp:  2             [SII]6716      5.052      0.31     -32    37
# Comp:  2             [SII]6731      3.533      0.31     -32    37
# Comp:  2              HeII4687    0.03931      0.31     -32    37
# Comp:  2               HeI5876     0.3275      0.31     -32    37
# Comp:  2          [OIII]5007_d      5.567      0.39     -32    37
# Comp:  2            [OI]6300_d     0.9783      0.39     -32    37
# Comp:  2           [NII]6583_d      6.434      0.39     -32    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        47
#  comp.  1:       -33        23
#  comp.  2:       -36        37
# chi2/DOF: 0.5388; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.577      0.30     -33    23
# Comp:  1                 Hbeta      5.828      0.30     -33    23
# Comp:  1                Halpha      18.31      0.30     -33    23
# Comp:  2             [SII]6716      5.087      0.31     -36    37
# Comp:  2             [SII]6731      3.540      0.31     -36    37
# Comp:  2              HeII4687     0.1971      0.31     -36    37
# Comp:  2               HeI5876     0.1916      0.31     -36    37
# Comp:  2          [OIII]5007_d      5.368      0.39     -36    37
# Comp:  2            [OI]6300_d     0.8911      0.39     -36    37
# Comp:  2           [NII]6583_d      6.695      0.39     -36    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -30        36
#  comp.  2:       -36        38
# chi2/DOF: 0.5405; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.379      0.31     -30    36
# Comp:  1                 Hbeta      6.115      0.31     -30    36
# Comp:  1                Halpha      19.38      0.31     -30    36
# Comp:  2             [SII]6716      4.915      0.31     -36    38
# Comp:  2             [SII]6731      3.730      0.31     -36    38
# Comp:  2              HeII4687     0.3212      0.31     -36    38
# Comp:  2               HeI5876     0.3332      0.31     -36    38
# Comp:  2          [OIII]5007_d      5.375      0.39     -36    38
# Comp:  2            [OI]6300_d     0.8434      0.39     -36    38
# Comp:  2           [NII]6583_d      6.647      0.39     -36    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        27
#  comp.  1:       -32        33
#  comp.  2:       -36        37
# chi2/DOF: 0.5415; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.853      0.31     -32    33
# Comp:  1                 Hbeta      6.366      0.31     -32    33
# Comp:  1                Halpha      19.33      0.31     -32    33
# Comp:  2             [SII]6716      5.047      0.31     -36    37
# Comp:  2             [SII]6731      3.515      0.31     -36    37
# Comp:  2              HeII4687      0.000      0.31     -36    37
# Comp:  2               HeI5876     0.4282      0.31     -36    37
# Comp:  2          [OIII]5007_d      6.033      0.39     -36    37
# Comp:  2            [OI]6300_d      1.019      0.39     -36    37
# Comp:  2           [NII]6583_d      6.530      0.39     -36    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        33
#  comp.  1:       -32        29
#  comp.  2:       -35        34
# chi2/DOF: 0.5443; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.334      0.30     -32    29
# Comp:  1                 Hbeta      6.459      0.30     -32    29
# Comp:  1                Halpha      18.80      0.30     -32    29
# Comp:  2             [SII]6716      5.026      0.31     -35    34
# Comp:  2             [SII]6731      3.579      0.31     -35    34
# Comp:  2              HeII4687    0.07241      0.31     -35    34
# Comp:  2               HeI5876     0.4511      0.31     -35    34
# Comp:  2          [OIII]5007_d      5.614      0.39     -35    34
# Comp:  2            [OI]6300_d     0.8367      0.39     -35    34
# Comp:  2           [NII]6583_d      6.577      0.39     -35    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -33        29
#  comp.  2:       -33        29
# chi2/DOF: 0.5438; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.408      0.30     -33    29
# Comp:  1                 Hbeta      5.722      0.30     -33    29
# Comp:  1                Halpha      18.52      0.30     -33    29
# Comp:  2             [SII]6716      5.089      0.30     -33    29
# Comp:  2             [SII]6731      3.523      0.30     -33    29
# Comp:  2              HeII4687      0.000      0.30     -33    29
# Comp:  2               HeI5876     0.3687      0.30     -33    29
# Comp:  2          [OIII]5007_d      5.912      0.38     -33    29
# Comp:  2            [OI]6300_d     0.7095      0.38     -33    29
# Comp:  2           [NII]6583_d      6.494      0.38     -33    29
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.15284316, 0.33048473, 0.43855992, 0.2198705 , 0.14802171,
#        0.11042341, 0.12389274, 0.33268603, 0.15879134, 0.16272472])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.12472402,  6.02904336, 25.7072706 ,  7.00872834,  4.9583605 ,
#         0.        ,  0.42271149,  5.84873904,  1.19910208,  8.99745502])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0        Hgamma  0.304454    0.021901
# 1         Hbeta  0.863909    0.047356
# 2        Halpha  3.683628    0.062842
# 3     [SII]6716  1.004290    0.031506
# 4     [SII]6731  0.710490    0.021210
# 5      HeII4687  0.000000    0.015823
# 6       HeI5876  0.060571    0.017753
# 7  [OIII]5007_d  0.838073    0.047671
# 8    [OI]6300_d  0.171821    0.022753
# 9   [NII]6583_d  1.289257    0.023317
#           Name      Flux  Error_flux
# 0       Hgamma  0.304454    0.021901
# 1        Hbeta  0.863909    0.047356
# 2       Halpha  3.683628    0.062842
# 3    [SII]6716  1.004290    0.031506
# 4    [SII]6731  0.710490    0.021210
# 5     HeII4687  0.000000    0.015823
# 6      HeI5876  0.060571    0.017753
# 7   [OIII]4959  0.209518    0.047671
# 8   [OIII]5007  0.628555    0.047671
# 9     [OI]6300  0.128866    0.022753
# 10    [OI]6364  0.042955    0.022753
# 11   [NII]6548  0.322314    0.023317
# 12   [NII]6583  0.966943    0.023317

# %%
np.median(flux_rf_rebin)
# Out:
# 0.14329129119964534
