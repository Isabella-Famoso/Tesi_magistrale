# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_1/FORS2.2021-10-05T04_55_53.494/Spectra_extraction/redshift.txt")
z = red[4][0] 
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4228.18435644 4229.6393881  4231.09441976 ... 6973.82909277 6975.28412442
#  6976.73915608] [0.04235426 0.02490411 0.08323615 ... 0.02951425 0.02683947 0.03117726] [0.01729172 0.01729172 0.01729172 ... 0.01729172 0.01729172 0.01729172]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11409218 2.11481969 2.11554721 ... 3.48691455 3.48764206 3.48836958]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3337, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314399512

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
# chi2/DOF: 0.1532; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
# chi2/DOF: 0.04189; DOF: 2020; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([25.6374001 ,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -0         1
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5990; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.696      0.98     -27    30
# Comp:  1                 Hbeta      6.003      0.98     -27    30
# Comp:  1                Halpha      25.38      0.98     -27    30
# Comp:  2             [SII]6716      7.429      0.95     -28    20
# Comp:  2             [SII]6731      5.251      0.95     -28    20
# Comp:  2              HeII4687      0.000      0.95     -28    20
# Comp:  2               HeI5876      1.256      0.95     -28    20
# Comp:  2          [OIII]5007_d      8.084       1.2     -28    20
# Comp:  2            [OI]6300_d      1.566       1.2     -28    20
# Comp:  2           [NII]6583_d      7.515       1.2     -28    20
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  5.489; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  9.565; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  39.58; gas flux:     35 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  11.92; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   8.81; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.972; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  9.899; gas flux:      8 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.982; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  9.314; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -28        34
#  comp.  2:       -30        16
# chi2/DOF: 0.5967; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.966      0.99     -28    34
# Comp:  1                 Hbeta      7.280      0.99     -28    34
# Comp:  1                Halpha      26.16      0.99     -28    34
# Comp:  2             [SII]6716      7.451      0.94     -30    16
# Comp:  2             [SII]6731      4.856      0.94     -30    16
# Comp:  2              HeII4687    0.06731      0.94     -30    16
# Comp:  2               HeI5876      1.240      0.94     -30    16
# Comp:  2          [OIII]5007_d      8.607       1.2     -30    16
# Comp:  2            [OI]6300_d      1.724       1.2     -30    16
# Comp:  2           [NII]6583_d      7.493       1.2     -30    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        20
#  comp.  1:       -27        30
#  comp.  2:       -28        19
# chi2/DOF: 0.5962; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.272      0.98     -27    30
# Comp:  1                 Hbeta      6.384      0.98     -27    30
# Comp:  1                Halpha      25.10      0.98     -27    30
# Comp:  2             [SII]6716      7.752      0.95     -28    19
# Comp:  2             [SII]6731      5.081      0.95     -28    19
# Comp:  2              HeII4687      0.000      0.95     -28    19
# Comp:  2               HeI5876      1.098      0.95     -28    19
# Comp:  2          [OIII]5007_d      7.990       1.2     -28    19
# Comp:  2            [OI]6300_d     0.9867       1.2     -28    19
# Comp:  2           [NII]6583_d      7.733       1.2     -28    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        49
#  comp.  1:       -27        30
#  comp.  2:       -28        19
# chi2/DOF: 0.5963; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.735      0.98     -27    30
# Comp:  1                 Hbeta      6.149      0.98     -27    30
# Comp:  1                Halpha      25.89      0.98     -27    30
# Comp:  2             [SII]6716      7.190      0.95     -28    19
# Comp:  2             [SII]6731      5.320      0.95     -28    19
# Comp:  2              HeII4687      0.000      0.95     -28    19
# Comp:  2               HeI5876      1.292      0.95     -28    19
# Comp:  2          [OIII]5007_d      7.842       1.2     -28    19
# Comp:  2            [OI]6300_d      2.200       1.2     -28    19
# Comp:  2           [NII]6583_d      7.857       1.2     -28    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0         1
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5951; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.799      0.98     -27    30
# Comp:  1                 Hbeta      5.642      0.98     -27    30
# Comp:  1                Halpha      25.57      0.98     -27    30
# Comp:  2             [SII]6716      7.348      0.95     -28    20
# Comp:  2             [SII]6731      5.582      0.95     -28    20
# Comp:  2              HeII4687     0.2759      0.95     -28    20
# Comp:  2               HeI5876      1.331      0.95     -28    20
# Comp:  2          [OIII]5007_d      7.371       1.2     -28    20
# Comp:  2            [OI]6300_d      2.206       1.2     -28    20
# Comp:  2           [NII]6583_d      7.761       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        30
#  comp.  1:       -27        30
#  comp.  2:       -28        19
# chi2/DOF: 0.5974; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.565      0.98     -27    30
# Comp:  1                 Hbeta      5.421      0.98     -27    30
# Comp:  1                Halpha      25.26      0.98     -27    30
# Comp:  2             [SII]6716      7.544      0.95     -28    19
# Comp:  2             [SII]6731      4.981      0.95     -28    19
# Comp:  2              HeII4687      0.000      0.95     -28    19
# Comp:  2               HeI5876      1.256      0.95     -28    19
# Comp:  2          [OIII]5007_d      8.405       1.2     -28    19
# Comp:  2            [OI]6300_d      1.489       1.2     -28    19
# Comp:  2           [NII]6583_d      7.293       1.2     -28    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -26        26
#  comp.  2:       -26        21
# chi2/DOF: 0.5916; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.950      0.97     -26    26
# Comp:  1                 Hbeta      7.114      0.97     -26    26
# Comp:  1                Halpha      25.56      0.97     -26    26
# Comp:  2             [SII]6716      7.689      0.96     -26    21
# Comp:  2             [SII]6731      5.237      0.96     -26    21
# Comp:  2              HeII4687      0.000      0.96     -26    21
# Comp:  2               HeI5876      1.139      0.96     -26    21
# Comp:  2          [OIII]5007_d      7.796       1.2     -26    21
# Comp:  2            [OI]6300_d      1.176       1.2     -26    21
# Comp:  2           [NII]6583_d      7.479       1.2     -26    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -28        33
#  comp.  2:       -28         1
# chi2/DOF: 0.5943; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.671      0.98     -28    33
# Comp:  1                 Hbeta      7.706      0.98     -28    33
# Comp:  1                Halpha      26.19      0.98     -28    33
# Comp:  2             [SII]6716      7.110      0.93     -28     1
# Comp:  2             [SII]6731      4.730      0.93     -28     1
# Comp:  2              HeII4687      0.000      0.93     -28     1
# Comp:  2               HeI5876      1.092      0.93     -28     1
# Comp:  2          [OIII]5007_d      7.663       1.2     -28     1
# Comp:  2            [OI]6300_d      1.688       1.2     -28     1
# Comp:  2           [NII]6583_d      7.694       1.2     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       108
#  comp.  1:       -28        26
#  comp.  2:       -24        20
# chi2/DOF: 0.5941; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.972      0.97     -28    26
# Comp:  1                 Hbeta      5.484      0.97     -28    26
# Comp:  1                Halpha      25.42      0.97     -28    26
# Comp:  2             [SII]6716      7.667      0.95     -24    20
# Comp:  2             [SII]6731      4.916      0.95     -24    20
# Comp:  2              HeII4687    0.08603      0.95     -24    20
# Comp:  2               HeI5876      1.340      0.95     -24    20
# Comp:  2          [OIII]5007_d      7.558       1.2     -24    20
# Comp:  2            [OI]6300_d      1.677       1.2     -24    20
# Comp:  2           [NII]6583_d      7.379       1.2     -24    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        37
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5953; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.943      0.98     -27    30
# Comp:  1                 Hbeta      6.180      0.98     -27    30
# Comp:  1                Halpha      25.88      0.98     -27    30
# Comp:  2             [SII]6716      7.357      0.95     -28    20
# Comp:  2             [SII]6731      4.919      0.95     -28    20
# Comp:  2              HeII4687     0.2033      0.95     -28    20
# Comp:  2               HeI5876      1.218      0.95     -28    20
# Comp:  2          [OIII]5007_d      8.482       1.2     -28    20
# Comp:  2            [OI]6300_d      1.484       1.2     -28    20
# Comp:  2           [NII]6583_d      7.640       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -27        29
#  comp.  2:       -31        20
# chi2/DOF: 0.5975; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.706      0.97     -27    29
# Comp:  1                 Hbeta      6.391      0.97     -27    29
# Comp:  1                Halpha      25.49      0.97     -27    29
# Comp:  2             [SII]6716      7.327      0.95     -31    20
# Comp:  2             [SII]6731      5.300      0.95     -31    20
# Comp:  2              HeII4687    0.01904      0.95     -31    20
# Comp:  2               HeI5876      1.001      0.95     -31    20
# Comp:  2          [OIII]5007_d      8.586       1.2     -31    20
# Comp:  2            [OI]6300_d      1.582       1.2     -31    20
# Comp:  2           [NII]6583_d      7.348       1.2     -31    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        32
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5949; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.026      0.98     -27    30
# Comp:  1                 Hbeta      6.610      0.98     -27    30
# Comp:  1                Halpha      26.15      0.98     -27    30
# Comp:  2             [SII]6716      7.531      0.95     -28    20
# Comp:  2             [SII]6731      4.914      0.95     -28    20
# Comp:  2              HeII4687      0.000      0.95     -28    20
# Comp:  2               HeI5876      1.003      0.95     -28    20
# Comp:  2          [OIII]5007_d      8.823       1.2     -28    20
# Comp:  2            [OI]6300_d      1.523       1.2     -28    20
# Comp:  2           [NII]6583_d      7.288       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -29        25
#  comp.  2:       -30        12
# chi2/DOF: 0.5965; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.664      0.96     -29    25
# Comp:  1                 Hbeta      6.809      0.96     -29    25
# Comp:  1                Halpha      25.65      0.96     -29    25
# Comp:  2             [SII]6716      7.343      0.94     -30    12
# Comp:  2             [SII]6731      5.364      0.94     -30    12
# Comp:  2              HeII4687      0.000      0.94     -30    12
# Comp:  2               HeI5876      1.102      0.94     -30    12
# Comp:  2          [OIII]5007_d      7.881       1.2     -30    12
# Comp:  2            [OI]6300_d      2.179       1.2     -30    12
# Comp:  2           [NII]6583_d      7.697       1.2     -30    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -25        35
#  comp.  2:       -30        11
# chi2/DOF: 0.5971; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.825      0.99     -25    35
# Comp:  1                 Hbeta      6.850      0.99     -25    35
# Comp:  1                Halpha      26.01      0.99     -25    35
# Comp:  2             [SII]6716      6.942      0.94     -30    11
# Comp:  2             [SII]6731      5.146      0.94     -30    11
# Comp:  2              HeII4687      0.000      0.94     -30    11
# Comp:  2               HeI5876      1.149      0.94     -30    11
# Comp:  2          [OIII]5007_d      7.574       1.2     -30    11
# Comp:  2            [OI]6300_d      1.547       1.2     -30    11
# Comp:  2           [NII]6583_d      7.151       1.2     -30    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        34
#  comp.  1:       -29        33
#  comp.  2:       -35        29
# chi2/DOF: 0.5950; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.665      0.99     -29    33
# Comp:  1                 Hbeta      7.108      0.99     -29    33
# Comp:  1                Halpha      27.00      0.99     -29    33
# Comp:  2             [SII]6716      7.574      0.97     -35    29
# Comp:  2             [SII]6731      5.441      0.97     -35    29
# Comp:  2              HeII4687    0.07164      0.97     -35    29
# Comp:  2               HeI5876      1.324      0.97     -35    29
# Comp:  2          [OIII]5007_d      7.946       1.2     -35    29
# Comp:  2            [OI]6300_d      1.826       1.2     -35    29
# Comp:  2           [NII]6583_d      7.851       1.2     -35    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -30        34
#  comp.  2:       -28         3
# chi2/DOF: 0.5950; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.183      0.99     -30    34
# Comp:  1                 Hbeta      5.608      0.99     -30    34
# Comp:  1                Halpha      25.81      0.99     -30    34
# Comp:  2             [SII]6716      7.189      0.93     -28     3
# Comp:  2             [SII]6731      4.976      0.93     -28     3
# Comp:  2              HeII4687      0.000      0.93     -28     3
# Comp:  2               HeI5876      1.158      0.93     -28     3
# Comp:  2          [OIII]5007_d      7.522       1.2     -28     3
# Comp:  2            [OI]6300_d     0.9065       1.2     -28     3
# Comp:  2           [NII]6583_d      7.804       1.2     -28     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        14
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5956; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.149      0.98     -27    30
# Comp:  1                 Hbeta      7.155      0.98     -27    30
# Comp:  1                Halpha      25.78      0.98     -27    30
# Comp:  2             [SII]6716      7.398      0.95     -28    20
# Comp:  2             [SII]6731      5.365      0.95     -28    20
# Comp:  2              HeII4687    0.03985      0.95     -28    20
# Comp:  2               HeI5876      1.256      0.95     -28    20
# Comp:  2          [OIII]5007_d      7.473       1.2     -28    20
# Comp:  2            [OI]6300_d      2.119       1.2     -28    20
# Comp:  2           [NII]6583_d      7.395       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        31
#  comp.  1:       -27        30
#  comp.  2:       -28        19
# chi2/DOF: 0.5973; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.075      0.98     -27    30
# Comp:  1                 Hbeta      6.154      0.98     -27    30
# Comp:  1                Halpha      25.63      0.98     -27    30
# Comp:  2             [SII]6716      7.405      0.95     -28    19
# Comp:  2             [SII]6731      5.153      0.95     -28    19
# Comp:  2              HeII4687      0.000      0.95     -28    19
# Comp:  2               HeI5876      1.018      0.95     -28    19
# Comp:  2          [OIII]5007_d      7.858       1.2     -28    19
# Comp:  2            [OI]6300_d      1.448       1.2     -28    19
# Comp:  2           [NII]6583_d      7.575       1.2     -28    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -27        32
#  comp.  2:       -29        33
# chi2/DOF: 0.5960; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.106      0.98     -27    32
# Comp:  1                 Hbeta      6.037      0.98     -27    32
# Comp:  1                Halpha      26.19      0.98     -27    32
# Comp:  2             [SII]6716      8.005      0.98     -29    33
# Comp:  2             [SII]6731      5.852      0.98     -29    33
# Comp:  2              HeII4687     0.2084      0.98     -29    33
# Comp:  2               HeI5876      1.445      0.98     -29    33
# Comp:  2          [OIII]5007_d      9.103       1.2     -29    33
# Comp:  2            [OI]6300_d      1.851       1.2     -29    33
# Comp:  2           [NII]6583_d      7.968       1.2     -29    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:       -26        28
#  comp.  2:       -27         6
# chi2/DOF: 0.5963; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.852      0.97     -26    28
# Comp:  1                 Hbeta      6.374      0.97     -26    28
# Comp:  1                Halpha      25.13      0.97     -26    28
# Comp:  2             [SII]6716      6.897      0.93     -27     6
# Comp:  2             [SII]6731      4.909      0.93     -27     6
# Comp:  2              HeII4687     0.1530      0.93     -27     6
# Comp:  2               HeI5876      1.070      0.93     -27     6
# Comp:  2          [OIII]5007_d      7.646       1.2     -27     6
# Comp:  2            [OI]6300_d     0.9850       1.2     -27     6
# Comp:  2           [NII]6583_d      7.187       1.2     -27     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -25        39
#  comp.  2:       -27        18
# chi2/DOF: 0.5947; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.682       1.0     -25    39
# Comp:  1                 Hbeta      7.089       1.0     -25    39
# Comp:  1                Halpha      26.82       1.0     -25    39
# Comp:  2             [SII]6716      7.380      0.95     -27    18
# Comp:  2             [SII]6731      5.495      0.95     -27    18
# Comp:  2              HeII4687    0.01413      0.95     -27    18
# Comp:  2               HeI5876      1.174      0.95     -27    18
# Comp:  2          [OIII]5007_d      7.726       1.2     -27    18
# Comp:  2            [OI]6300_d      1.130       1.2     -27    18
# Comp:  2           [NII]6583_d      7.504       1.2     -27    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        41
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5957; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.484      0.98     -27    30
# Comp:  1                 Hbeta      5.211      0.98     -27    30
# Comp:  1                Halpha      25.36      0.98     -27    30
# Comp:  2             [SII]6716      7.656      0.95     -28    20
# Comp:  2             [SII]6731      5.208      0.95     -28    20
# Comp:  2              HeII4687      0.000      0.95     -28    20
# Comp:  2               HeI5876      1.091      0.95     -28    20
# Comp:  2          [OIII]5007_d      7.797       1.2     -28    20
# Comp:  2            [OI]6300_d      1.932       1.2     -28    20
# Comp:  2           [NII]6583_d      7.451       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -28        35
#  comp.  2:       -27        12
# chi2/DOF: 0.5962; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.008      0.99     -28    35
# Comp:  1                 Hbeta      6.398      0.99     -28    35
# Comp:  1                Halpha      25.74      0.99     -28    35
# Comp:  2             [SII]6716      7.348      0.94     -27    12
# Comp:  2             [SII]6731      5.431      0.94     -27    12
# Comp:  2              HeII4687     0.1552      0.94     -27    12
# Comp:  2               HeI5876      1.293      0.94     -27    12
# Comp:  2          [OIII]5007_d      7.465       1.2     -27    12
# Comp:  2            [OI]6300_d      1.321       1.2     -27    12
# Comp:  2           [NII]6583_d      7.357       1.2     -27    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -29        29
#  comp.  2:       -30        30
# chi2/DOF: 0.5939; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.112      0.97     -29    29
# Comp:  1                 Hbeta      6.323      0.97     -29    29
# Comp:  1                Halpha      25.42      0.97     -29    29
# Comp:  2             [SII]6716      8.130      0.98     -30    30
# Comp:  2             [SII]6731      5.409      0.98     -30    30
# Comp:  2              HeII4687    0.07179      0.98     -30    30
# Comp:  2               HeI5876      1.034      0.98     -30    30
# Comp:  2          [OIII]5007_d      7.981       1.2     -30    30
# Comp:  2            [OI]6300_d      2.115       1.2     -30    30
# Comp:  2           [NII]6583_d      7.761       1.2     -30    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -29        22
#  comp.  2:       -27        24
# chi2/DOF: 0.5939; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.704      0.96     -29    22
# Comp:  1                 Hbeta      5.174      0.96     -29    22
# Comp:  1                Halpha      24.82      0.96     -29    22
# Comp:  2             [SII]6716      7.771      0.96     -27    24
# Comp:  2             [SII]6731      5.693      0.96     -27    24
# Comp:  2              HeII4687    0.01679      0.96     -27    24
# Comp:  2               HeI5876      1.351      0.96     -27    24
# Comp:  2          [OIII]5007_d      7.756       1.2     -27    24
# Comp:  2            [OI]6300_d      2.004       1.2     -27    24
# Comp:  2           [NII]6583_d      7.283       1.2     -27    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -30        28
#  comp.  2:       -25        14
# chi2/DOF: 0.5954; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.343      0.97     -30    28
# Comp:  1                 Hbeta      6.023      0.97     -30    28
# Comp:  1                Halpha      25.61      0.97     -30    28
# Comp:  2             [SII]6716      7.655      0.94     -25    14
# Comp:  2             [SII]6731      5.183      0.94     -25    14
# Comp:  2              HeII4687      0.000      0.94     -25    14
# Comp:  2               HeI5876      1.621      0.94     -25    14
# Comp:  2          [OIII]5007_d      7.751       1.2     -25    14
# Comp:  2            [OI]6300_d     0.9422       1.2     -25    14
# Comp:  2           [NII]6583_d      7.688       1.2     -25    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:       -26        30
#  comp.  2:       -31        29
# chi2/DOF: 0.5938; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.525      0.98     -26    30
# Comp:  1                 Hbeta      6.011      0.98     -26    30
# Comp:  1                Halpha      25.33      0.98     -26    30
# Comp:  2             [SII]6716      7.411      0.97     -31    29
# Comp:  2             [SII]6731      5.328      0.97     -31    29
# Comp:  2              HeII4687     0.1975      0.97     -31    29
# Comp:  2               HeI5876      1.298      0.97     -31    29
# Comp:  2          [OIII]5007_d      8.589       1.2     -31    29
# Comp:  2            [OI]6300_d      1.641       1.2     -31    29
# Comp:  2           [NII]6583_d      7.610       1.2     -31    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11         1
#  comp.  1:       -28        33
#  comp.  2:       -31        32
# chi2/DOF: 0.5964; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.080      0.99     -28    33
# Comp:  1                 Hbeta      6.700      0.99     -28    33
# Comp:  1                Halpha      25.51      0.99     -28    33
# Comp:  2             [SII]6716      7.698      0.98     -31    32
# Comp:  2             [SII]6731      5.149      0.98     -31    32
# Comp:  2              HeII4687     0.3379      0.98     -31    32
# Comp:  2               HeI5876      1.024      0.98     -31    32
# Comp:  2          [OIII]5007_d      8.544       1.2     -31    32
# Comp:  2            [OI]6300_d      1.799       1.2     -31    32
# Comp:  2           [NII]6583_d      7.663       1.2     -31    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -26        40
#  comp.  2:       -26         9
# chi2/DOF: 0.5960; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.075       1.0     -26    40
# Comp:  1                 Hbeta      6.467       1.0     -26    40
# Comp:  1                Halpha      25.78       1.0     -26    40
# Comp:  2             [SII]6716      7.655      0.94     -26     9
# Comp:  2             [SII]6731      4.888      0.94     -26     9
# Comp:  2              HeII4687      0.000      0.94     -26     9
# Comp:  2               HeI5876      1.261      0.94     -26     9
# Comp:  2          [OIII]5007_d      8.042       1.2     -26     9
# Comp:  2            [OI]6300_d     0.9685       1.2     -26     9
# Comp:  2           [NII]6583_d      7.720       1.2     -26     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:       -27        31
#  comp.  2:       -29        14
# chi2/DOF: 0.5919; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.894      0.98     -27    31
# Comp:  1                 Hbeta      7.593      0.98     -27    31
# Comp:  1                Halpha      25.78      0.98     -27    31
# Comp:  2             [SII]6716      7.204      0.94     -29    14
# Comp:  2             [SII]6731      5.102      0.94     -29    14
# Comp:  2              HeII4687      0.000      0.94     -29    14
# Comp:  2               HeI5876      1.131      0.94     -29    14
# Comp:  2          [OIII]5007_d      7.696       1.2     -29    14
# Comp:  2            [OI]6300_d     0.9544       1.2     -29    14
# Comp:  2           [NII]6583_d      7.354       1.2     -29    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -27        36
#  comp.  2:       -29        18
# chi2/DOF: 0.5970; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.631      0.99     -27    36
# Comp:  1                 Hbeta      6.962      0.99     -27    36
# Comp:  1                Halpha      25.46      0.99     -27    36
# Comp:  2             [SII]6716      7.239      0.95     -29    18
# Comp:  2             [SII]6731      5.301      0.95     -29    18
# Comp:  2              HeII4687     0.3237      0.95     -29    18
# Comp:  2               HeI5876      1.401      0.95     -29    18
# Comp:  2          [OIII]5007_d      8.197       1.2     -29    18
# Comp:  2            [OI]6300_d      1.601       1.2     -29    18
# Comp:  2           [NII]6583_d      7.466       1.2     -29    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:       -26        28
#  comp.  2:       -27        29
# chi2/DOF: 0.5975; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.624      0.97     -26    28
# Comp:  1                 Hbeta      5.139      0.97     -26    28
# Comp:  1                Halpha      25.24      0.97     -26    28
# Comp:  2             [SII]6716      7.548      0.97     -27    29
# Comp:  2             [SII]6731      5.329      0.97     -27    29
# Comp:  2              HeII4687     0.2811      0.97     -27    29
# Comp:  2               HeI5876      1.207      0.97     -27    29
# Comp:  2          [OIII]5007_d      8.548       1.2     -27    29
# Comp:  2            [OI]6300_d      1.753       1.2     -27    29
# Comp:  2           [NII]6583_d      7.769       1.2     -27    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        65
#  comp.  1:       -25        31
#  comp.  2:       -29        25
# chi2/DOF: 0.5957; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.484      0.98     -25    31
# Comp:  1                 Hbeta      6.560      0.98     -25    31
# Comp:  1                Halpha      26.15      0.98     -25    31
# Comp:  2             [SII]6716      7.843      0.96     -29    25
# Comp:  2             [SII]6731      5.083      0.96     -29    25
# Comp:  2              HeII4687      0.000      0.96     -29    25
# Comp:  2               HeI5876      1.330      0.96     -29    25
# Comp:  2          [OIII]5007_d      8.493       1.2     -29    25
# Comp:  2            [OI]6300_d     0.7323       1.2     -29    25
# Comp:  2           [NII]6583_d      7.541       1.2     -29    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15        69
#  comp.  1:       -27        30
#  comp.  2:       -26        26
# chi2/DOF: 0.5953; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.630      0.98     -27    30
# Comp:  1                 Hbeta      5.430      0.98     -27    30
# Comp:  1                Halpha      25.88      0.98     -27    30
# Comp:  2             [SII]6716      7.787      0.97     -26    26
# Comp:  2             [SII]6731      5.033      0.97     -26    26
# Comp:  2              HeII4687      0.000      0.97     -26    26
# Comp:  2               HeI5876      1.165      0.97     -26    26
# Comp:  2          [OIII]5007_d      7.838       1.2     -26    26
# Comp:  2            [OI]6300_d      2.104       1.2     -26    26
# Comp:  2           [NII]6583_d      7.329       1.2     -26    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        16
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5975; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.631      0.98     -27    30
# Comp:  1                 Hbeta      6.186      0.98     -27    30
# Comp:  1                Halpha      25.38      0.98     -27    30
# Comp:  2             [SII]6716      7.460      0.95     -28    20
# Comp:  2             [SII]6731      4.995      0.95     -28    20
# Comp:  2              HeII4687      0.000      0.95     -28    20
# Comp:  2               HeI5876      1.389      0.95     -28    20
# Comp:  2          [OIII]5007_d      9.003       1.2     -28    20
# Comp:  2            [OI]6300_d      2.139       1.2     -28    20
# Comp:  2           [NII]6583_d      7.257       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9         1
#  comp.  1:       -26        27
#  comp.  2:       -27        24
# chi2/DOF: 0.5942; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.026      0.97     -26    27
# Comp:  1                 Hbeta      6.014      0.97     -26    27
# Comp:  1                Halpha      25.03      0.97     -26    27
# Comp:  2             [SII]6716      7.594      0.96     -27    24
# Comp:  2             [SII]6731      5.447      0.96     -27    24
# Comp:  2              HeII4687      0.000      0.96     -27    24
# Comp:  2               HeI5876      1.575      0.96     -27    24
# Comp:  2          [OIII]5007_d      7.190       1.2     -27    24
# Comp:  2            [OI]6300_d      1.882       1.2     -27    24
# Comp:  2           [NII]6583_d      7.752       1.2     -27    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:       -25        23
#  comp.  2:       -27        18
# chi2/DOF: 0.5941; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.762      0.96     -25    23
# Comp:  1                 Hbeta      6.643      0.96     -25    23
# Comp:  1                Halpha      25.06      0.96     -25    23
# Comp:  2             [SII]6716      7.415      0.95     -27    18
# Comp:  2             [SII]6731      4.872      0.95     -27    18
# Comp:  2              HeII4687      0.000      0.95     -27    18
# Comp:  2               HeI5876      1.607      0.95     -27    18
# Comp:  2          [OIII]5007_d      8.872       1.2     -27    18
# Comp:  2            [OI]6300_d      2.124       1.2     -27    18
# Comp:  2           [NII]6583_d      7.535       1.2     -27    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -28        32
#  comp.  2:       -31        21
# chi2/DOF: 0.5927; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.599      0.98     -28    32
# Comp:  1                 Hbeta      6.074      0.98     -28    32
# Comp:  1                Halpha      25.53      0.98     -28    32
# Comp:  2             [SII]6716      7.712      0.95     -31    21
# Comp:  2             [SII]6731      5.058      0.95     -31    21
# Comp:  2              HeII4687     0.1588      0.95     -31    21
# Comp:  2               HeI5876      1.571      0.95     -31    21
# Comp:  2          [OIII]5007_d      7.733       1.2     -31    21
# Comp:  2            [OI]6300_d     0.8657       1.2     -31    21
# Comp:  2           [NII]6583_d      7.776       1.2     -31    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -27        32
#  comp.  2:       -32        21
# chi2/DOF: 0.5948; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.371      0.98     -27    32
# Comp:  1                 Hbeta      5.712      0.98     -27    32
# Comp:  1                Halpha      25.96      0.98     -27    32
# Comp:  2             [SII]6716      7.496      0.96     -32    21
# Comp:  2             [SII]6731      5.483      0.96     -32    21
# Comp:  2              HeII4687    0.02461      0.96     -32    21
# Comp:  2               HeI5876      1.380      0.96     -32    21
# Comp:  2          [OIII]5007_d      8.342       1.2     -32    21
# Comp:  2            [OI]6300_d      1.328       1.2     -32    21
# Comp:  2           [NII]6583_d      7.321       1.2     -32    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22         1
#  comp.  1:       -26        32
#  comp.  2:       -31        28
# chi2/DOF: 0.5928; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.689      0.98     -26    32
# Comp:  1                 Hbeta      6.445      0.98     -26    32
# Comp:  1                Halpha      25.84      0.98     -26    32
# Comp:  2             [SII]6716      7.646      0.97     -31    28
# Comp:  2             [SII]6731      5.760      0.97     -31    28
# Comp:  2              HeII4687     0.2853      0.97     -31    28
# Comp:  2               HeI5876      1.289      0.97     -31    28
# Comp:  2          [OIII]5007_d      8.665       1.2     -31    28
# Comp:  2            [OI]6300_d     0.9617       1.2     -31    28
# Comp:  2           [NII]6583_d      7.591       1.2     -31    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:       -25        35
#  comp.  2:       -27         1
# chi2/DOF: 0.5939; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        47
#  comp.  1:       -26        32
#  comp.  2:       -28         5
# chi2/DOF: 0.5941; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.377      0.98     -26    32
# Comp:  1                 Hbeta      6.301      0.98     -26    32
# Comp:  1                Halpha      25.29      0.98     -26    32
# Comp:  2             [SII]6716      7.298      0.93     -28     5
# Comp:  2             [SII]6731      4.784      0.93     -28     5
# Comp:  2              HeII4687      0.000      0.93     -28     5
# Comp:  2               HeI5876      1.380      0.93     -28     5
# Comp:  2          [OIII]5007_d      7.292       1.2     -28     5
# Comp:  2            [OI]6300_d      1.515       1.2     -28     5
# Comp:  2           [NII]6583_d      7.212       1.2     -28     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:       -27        26
#  comp.  2:       -27        16
# chi2/DOF: 0.5967; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.797      0.97     -27    26
# Comp:  1                 Hbeta      5.876      0.97     -27    26
# Comp:  1                Halpha      25.66      0.97     -27    26
# Comp:  2             [SII]6716      7.443      0.95     -27    16
# Comp:  2             [SII]6731      5.489      0.95     -27    16
# Comp:  2              HeII4687      0.000      0.95     -27    16
# Comp:  2               HeI5876     0.9788      0.95     -27    16
# Comp:  2          [OIII]5007_d      8.113       1.2     -27    16
# Comp:  2            [OI]6300_d      1.761       1.2     -27    16
# Comp:  2           [NII]6583_d      7.138       1.2     -27    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        26
#  comp.  1:       -27        30
#  comp.  2:       -28        19
# chi2/DOF: 0.5979; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.750      0.98     -27    30
# Comp:  1                 Hbeta      6.239      0.98     -27    30
# Comp:  1                Halpha      25.41      0.98     -27    30
# Comp:  2             [SII]6716      7.494      0.95     -28    19
# Comp:  2             [SII]6731      5.567      0.95     -28    19
# Comp:  2              HeII4687   0.003621      0.95     -28    19
# Comp:  2               HeI5876      1.259      0.95     -28    19
# Comp:  2          [OIII]5007_d      8.116       1.2     -28    19
# Comp:  2            [OI]6300_d      1.568       1.2     -28    19
# Comp:  2           [NII]6583_d      7.708       1.2     -28    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        32
#  comp.  1:       -27        30
#  comp.  2:       -28        20
# chi2/DOF: 0.5958; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.044      0.98     -27    30
# Comp:  1                 Hbeta      5.731      0.98     -27    30
# Comp:  1                Halpha      25.44      0.98     -27    30
# Comp:  2             [SII]6716      7.284      0.95     -28    20
# Comp:  2             [SII]6731      5.226      0.95     -28    20
# Comp:  2              HeII4687      0.000      0.95     -28    20
# Comp:  2               HeI5876      1.034      0.95     -28    20
# Comp:  2          [OIII]5007_d      8.796       1.2     -28    20
# Comp:  2            [OI]6300_d      1.552       1.2     -28    20
# Comp:  2           [NII]6583_d      7.724       1.2     -28    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         1
#  comp.  1:       -26        24
#  comp.  2:       -25        27
# chi2/DOF: 0.5951; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.842      0.96     -26    24
# Comp:  1                 Hbeta      6.639      0.96     -26    24
# Comp:  1                Halpha      25.49      0.96     -26    24
# Comp:  2             [SII]6716      7.569      0.97     -25    27
# Comp:  2             [SII]6731      5.366      0.97     -25    27
# Comp:  2              HeII4687      0.000      0.97     -25    27
# Comp:  2               HeI5876      1.304      0.97     -25    27
# Comp:  2          [OIII]5007_d      7.764       1.2     -25    27
# Comp:  2            [OI]6300_d      1.812       1.2     -25    27
# Comp:  2           [NII]6583_d      7.588       1.2     -25    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7       132
#  comp.  1:       -26        26
#  comp.  2:       -28        21
# chi2/DOF: 0.5941; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.225      0.97     -26    26
# Comp:  1                 Hbeta      5.151      0.97     -26    26
# Comp:  1                Halpha      25.06      0.97     -26    26
# Comp:  2             [SII]6716      7.257      0.95     -28    21
# Comp:  2             [SII]6731      5.612      0.95     -28    21
# Comp:  2              HeII4687     0.2208      0.95     -28    21
# Comp:  2               HeI5876      1.383      0.95     -28    21
# Comp:  2          [OIII]5007_d      7.745       1.2     -28    21
# Comp:  2            [OI]6300_d      2.313       1.2     -28    21
# Comp:  2           [NII]6583_d      7.611       1.2     -28    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         1
#  comp.  1:       -26        38
#  comp.  2:       -24        23
# chi2/DOF: 0.5923; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.338       1.0     -26    38
# Comp:  1                 Hbeta      7.243       1.0     -26    38
# Comp:  1                Halpha      26.40       1.0     -26    38
# Comp:  2             [SII]6716      7.531      0.96     -24    23
# Comp:  2             [SII]6731      4.868      0.96     -24    23
# Comp:  2              HeII4687      0.000      0.96     -24    23
# Comp:  2               HeI5876      1.166      0.96     -24    23
# Comp:  2          [OIII]5007_d      7.885       1.2     -24    23
# Comp:  2            [OI]6300_d      1.658       1.2     -24    23
# Comp:  2           [NII]6583_d      7.296       1.2     -24    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -30        33
#  comp.  2:       -27        28
# chi2/DOF: 0.5950; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.353      0.98     -30    33
# Comp:  1                 Hbeta      5.528      0.98     -30    33
# Comp:  1                Halpha      25.35      0.98     -30    33
# Comp:  2             [SII]6716      7.781      0.97     -27    28
# Comp:  2             [SII]6731      5.137      0.97     -27    28
# Comp:  2              HeII4687      0.000      0.97     -27    28
# Comp:  2               HeI5876      1.311      0.97     -27    28
# Comp:  2          [OIII]5007_d      8.237       1.2     -27    28
# Comp:  2            [OI]6300_d      1.451       1.2     -27    28
# Comp:  2           [NII]6583_d      7.221       1.2     -27    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:       -28        32
#  comp.  2:       -28        10
# chi2/DOF: 0.5965; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.645      0.98     -28    32
# Comp:  1                 Hbeta      6.092      0.98     -28    32
# Comp:  1                Halpha      25.15      0.98     -28    32
# Comp:  2             [SII]6716      7.257      0.94     -28    10
# Comp:  2             [SII]6731      4.972      0.94     -28    10
# Comp:  2              HeII4687     0.2231      0.94     -28    10
# Comp:  2               HeI5876      1.123      0.94     -28    10
# Comp:  2          [OIII]5007_d      8.595       1.2     -28    10
# Comp:  2            [OI]6300_d      1.363       1.2     -28    10
# Comp:  2           [NII]6583_d      7.272       1.2     -28    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -26        34
#  comp.  2:       -29        14
# chi2/DOF: 0.5959; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.168      0.99     -26    34
# Comp:  1                 Hbeta      5.897      0.99     -26    34
# Comp:  1                Halpha      25.54      0.99     -26    34
# Comp:  2             [SII]6716      7.099      0.94     -29    14
# Comp:  2             [SII]6731      5.484      0.94     -29    14
# Comp:  2              HeII4687     0.5311      0.94     -29    14
# Comp:  2               HeI5876      1.247      0.94     -29    14
# Comp:  2          [OIII]5007_d      8.064       1.2     -29    14
# Comp:  2            [OI]6300_d     0.8250       1.2     -29    14
# Comp:  2           [NII]6583_d      7.480       1.2     -29    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        58
#  comp.  1:       -27        30
#  comp.  2:       -29        20
# chi2/DOF: 0.5973; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.521      0.98     -27    30
# Comp:  1                 Hbeta      6.051      0.98     -27    30
# Comp:  1                Halpha      25.85      0.98     -27    30
# Comp:  2             [SII]6716      7.174      0.95     -29    20
# Comp:  2             [SII]6731      5.340      0.95     -29    20
# Comp:  2              HeII4687      0.000      0.95     -29    20
# Comp:  2               HeI5876      1.193      0.95     -29    20
# Comp:  2          [OIII]5007_d      8.236       1.2     -29    20
# Comp:  2            [OI]6300_d      1.589       1.2     -29    20
# Comp:  2           [NII]6583_d      7.516       1.2     -29    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -27        26
#  comp.  2:       -32        23
# chi2/DOF: 0.5979; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.854      0.97     -27    26
# Comp:  1                 Hbeta      6.147      0.97     -27    26
# Comp:  1                Halpha      25.05      0.97     -27    26
# Comp:  2             [SII]6716      7.478      0.96     -32    23
# Comp:  2             [SII]6731      5.600      0.96     -32    23
# Comp:  2              HeII4687      0.000      0.96     -32    23
# Comp:  2               HeI5876      1.012      0.96     -32    23
# Comp:  2          [OIII]5007_d      8.331       1.2     -32    23
# Comp:  2            [OI]6300_d      1.458       1.2     -32    23
# Comp:  2           [NII]6583_d      7.596       1.2     -32    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5       130
#  comp.  1:       -27        33
#  comp.  2:       -26         9
# chi2/DOF: 0.5952; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.786      0.99     -27    33
# Comp:  1                 Hbeta      6.767      0.99     -27    33
# Comp:  1                Halpha      25.14      0.99     -27    33
# Comp:  2             [SII]6716      7.298      0.94     -26     9
# Comp:  2             [SII]6731      5.123      0.94     -26     9
# Comp:  2              HeII4687      0.000      0.94     -26     9
# Comp:  2               HeI5876      1.270      0.94     -26     9
# Comp:  2          [OIII]5007_d      7.710       1.2     -26     9
# Comp:  2            [OI]6300_d     0.8090       1.2     -26     9
# Comp:  2           [NII]6583_d      7.693       1.2     -26     9
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.60227891, 0.59094732, 0.67396668, 0.37405598, 0.34550053,
#        0.14778076, 0.21184906, 0.49900443, 0.60280659, 0.33191181])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.34564432,  6.08633242, 34.74636643, 10.40762706,  7.37236108,
#         0.        ,  1.53935896,  8.44217646,  2.05744432, 10.31913391])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_5_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_5_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_5_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_5_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0        Hgamma  0.120256    0.021648
# 1         Hbeta  0.218767    0.021241
# 2        Halpha  1.248923    0.024225
# 3     [SII]6716  0.374092    0.013445
# 4     [SII]6731  0.264992    0.012419
# 5      HeII4687  0.000000    0.005312
# 6       HeI5876  0.055331    0.007615
# 7  [OIII]5007_d  0.303445    0.017936
# 8    [OI]6300_d  0.073953    0.021667
# 9   [NII]6583_d  0.370911    0.011930
#           Name      Flux  Error_flux
# 0       Hgamma  0.120256    0.021648
# 1        Hbeta  0.218767    0.021241
# 2       Halpha  1.248923    0.024225
# 3    [SII]6716  0.374092    0.013445
# 4    [SII]6731  0.264992    0.012419
# 5     HeII4687  0.000000    0.005312
# 6      HeI5876  0.055331    0.007615
# 7   [OIII]4959  0.075861    0.017936
# 8   [OIII]5007  0.227584    0.017936
# 9     [OI]6300  0.055465    0.021667
# 10    [OI]6364  0.018488    0.021667
# 11   [NII]6548  0.092728    0.011930
# 12   [NII]6583  0.278183    0.011930

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0359439821045489
