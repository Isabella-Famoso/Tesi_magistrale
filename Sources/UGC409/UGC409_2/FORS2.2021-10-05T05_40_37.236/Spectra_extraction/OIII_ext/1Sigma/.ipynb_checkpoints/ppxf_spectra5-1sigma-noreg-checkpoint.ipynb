# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC409/UGC409_2/FORS2.2021-10-05T05_40_37.236/Spectra_extraction/redshift.txt") 
z = red[4][0] 
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4228.80797632 4230.26322258 4231.71846884 ... 6974.85767102 6976.31291728
#  6977.76816354] [0.05615387 0.01250796 0.02317031 ... 0.01635796 0.01127489 0.01785727] [0.00813608 0.00813608 0.00813608 ... 0.00813608 0.00813608 0.00813608]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11440399 2.11513161 2.11585923 ... 3.48742884 3.48815646 3.48888408]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3336, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314399512

# %%
stars_templates.shape
# Out:
# (3336, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3336, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         1         1
# chi2/DOF: 0.4380; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
# chi2/DOF: 0.1074; DOF: 2016; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([38.33572064,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -12        28
#  comp.  2:       -11        31
# chi2/DOF: 1.073; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.310       1.2     -12    28
# Comp:  1                 Hbeta      14.20       1.2     -12    28
# Comp:  1                Halpha      39.57       1.2     -12    28
# Comp:  2             [SII]6716      7.175       1.2     -11    31
# Comp:  2             [SII]6731      4.518       1.2     -11    31
# Comp:  2              HeII4687     0.4560       1.2     -11    31
# Comp:  2               HeI5876      1.075       1.2     -11    31
# Comp:  2          [OIII]5007_d      15.96       1.6     -11    31
# Comp:  2            [OI]6300_d      1.117       1.6     -11    31
# Comp:  2           [NII]6583_d      9.269       1.6     -11    31
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  6.296; gas flux:      6 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  13.24; gas flux:     14 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  38.52; gas flux:     54 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  6.921; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  4.084; gas flux:      6 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.4482; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.057; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  11.72; gas flux:     17 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.7739; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  6.559; gas flux:     13 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        45        66
#  comp.  1:       -11        37
#  comp.  2:        -9        23
# chi2/DOF: 1.061; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.788       1.3     -11    37
# Comp:  1                 Hbeta      16.42       1.3     -11    37
# Comp:  1                Halpha      41.57       1.3     -11    37
# Comp:  2             [SII]6716      7.362       1.2      -9    23
# Comp:  2             [SII]6731      4.642       1.2      -9    23
# Comp:  2              HeII4687     0.2203       1.2      -9    23
# Comp:  2               HeI5876      1.574       1.2      -9    23
# Comp:  2          [OIII]5007_d      17.41       1.5      -9    23
# Comp:  2            [OI]6300_d      0.000       1.5      -9    23
# Comp:  2           [NII]6583_d      9.101       1.5      -9    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:        -9        29
#  comp.  2:        -3        15
# chi2/DOF: 1.063; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.377       1.2      -9    29
# Comp:  1                 Hbeta      13.70       1.2      -9    29
# Comp:  1                Halpha      39.13       1.2      -9    29
# Comp:  2             [SII]6716      7.454       1.2      -3    15
# Comp:  2             [SII]6731      4.528       1.2      -3    15
# Comp:  2              HeII4687     0.3720       1.2      -3    15
# Comp:  2               HeI5876      1.226       1.2      -3    15
# Comp:  2          [OIII]5007_d      15.29       1.5      -3    15
# Comp:  2            [OI]6300_d      2.339       1.5      -3    15
# Comp:  2           [NII]6583_d      9.781       1.5      -3    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         9
#  comp.  1:       -10        23
#  comp.  2:       -12        36
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.956       1.2     -10    23
# Comp:  1                 Hbeta      13.69       1.2     -10    23
# Comp:  1                Halpha      39.88       1.2     -10    23
# Comp:  2             [SII]6716      7.598       1.2     -12    36
# Comp:  2             [SII]6731      4.177       1.2     -12    36
# Comp:  2              HeII4687     0.5217       1.2     -12    36
# Comp:  2               HeI5876      1.610       1.2     -12    36
# Comp:  2          [OIII]5007_d      15.13       1.6     -12    36
# Comp:  2            [OI]6300_d      1.542       1.6     -12    36
# Comp:  2           [NII]6583_d      10.37       1.6     -12    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57       125
#  comp.  1:       -12        36
#  comp.  2:       -12        43
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.795       1.2     -12    36
# Comp:  1                 Hbeta      14.08       1.2     -12    36
# Comp:  1                Halpha      40.51       1.2     -12    36
# Comp:  2             [SII]6716      7.368       1.3     -12    43
# Comp:  2             [SII]6731      4.110       1.3     -12    43
# Comp:  2              HeII4687     0.8184       1.3     -12    43
# Comp:  2               HeI5876     0.9145       1.3     -12    43
# Comp:  2          [OIII]5007_d      15.25       1.6     -12    43
# Comp:  2            [OI]6300_d      0.000       1.6     -12    43
# Comp:  2           [NII]6583_d      9.351       1.6     -12    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -14        33
#  comp.  2:       -10        40
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.393       1.2     -14    33
# Comp:  1                 Hbeta      12.99       1.2     -14    33
# Comp:  1                Halpha      39.43       1.2     -14    33
# Comp:  2             [SII]6716      7.932       1.3     -10    40
# Comp:  2             [SII]6731      4.715       1.3     -10    40
# Comp:  2              HeII4687     0.5400       1.3     -10    40
# Comp:  2               HeI5876      1.188       1.3     -10    40
# Comp:  2          [OIII]5007_d      17.35       1.6     -10    40
# Comp:  2            [OI]6300_d      2.118       1.6     -10    40
# Comp:  2           [NII]6583_d      9.671       1.6     -10    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:        -9        28
#  comp.  2:        -6        33
# chi2/DOF: 1.062; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.246       1.2      -9    28
# Comp:  1                 Hbeta      16.50       1.2      -9    28
# Comp:  1                Halpha      40.20       1.2      -9    28
# Comp:  2             [SII]6716      7.332       1.2      -6    33
# Comp:  2             [SII]6731      4.467       1.2      -6    33
# Comp:  2              HeII4687     0.8022       1.2      -6    33
# Comp:  2               HeI5876      1.661       1.2      -6    33
# Comp:  2          [OIII]5007_d      15.76       1.6      -6    33
# Comp:  2            [OI]6300_d     0.4160       1.6      -6    33
# Comp:  2           [NII]6583_d      8.766       1.6      -6    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:       -13        41
#  comp.  2:       -12        22
# chi2/DOF: 1.061; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.745       1.3     -13    41
# Comp:  1                 Hbeta      16.69       1.3     -13    41
# Comp:  1                Halpha      42.55       1.3     -13    41
# Comp:  2             [SII]6716      7.384       1.2     -12    22
# Comp:  2             [SII]6731      4.741       1.2     -12    22
# Comp:  2              HeII4687     0.8590       1.2     -12    22
# Comp:  2               HeI5876     0.8804       1.2     -12    22
# Comp:  2          [OIII]5007_d      15.07       1.5     -12    22
# Comp:  2            [OI]6300_d      1.689       1.5     -12    22
# Comp:  2           [NII]6583_d      9.861       1.5     -12    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        27
#  comp.  1:       -10        20
#  comp.  2:        -7        39
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.129       1.2     -10    20
# Comp:  1                 Hbeta      13.39       1.2     -10    20
# Comp:  1                Halpha      39.08       1.2     -10    20
# Comp:  2             [SII]6716      8.377       1.3      -7    39
# Comp:  2             [SII]6731      4.676       1.3      -7    39
# Comp:  2              HeII4687     0.1157       1.3      -7    39
# Comp:  2               HeI5876      1.004       1.3      -7    39
# Comp:  2          [OIII]5007_d      16.11       1.6      -7    39
# Comp:  2            [OI]6300_d      2.126       1.6      -7    39
# Comp:  2           [NII]6583_d      9.229       1.6      -7    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        68
#  comp.  1:       -12        28
#  comp.  2:       -11        32
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.309       1.2     -12    28
# Comp:  1                 Hbeta      13.43       1.2     -12    28
# Comp:  1                Halpha      41.01       1.2     -12    28
# Comp:  2             [SII]6716      7.018       1.2     -11    32
# Comp:  2             [SII]6731      4.412       1.2     -11    32
# Comp:  2              HeII4687     0.1704       1.2     -11    32
# Comp:  2               HeI5876      1.088       1.2     -11    32
# Comp:  2          [OIII]5007_d      16.74       1.6     -11    32
# Comp:  2            [OI]6300_d    0.09749       1.6     -11    32
# Comp:  2           [NII]6583_d      8.958       1.6     -11    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        31
#  comp.  1:       -12        29
#  comp.  2:       -11        31
# chi2/DOF: 1.068; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.181       1.2     -12    29
# Comp:  1                 Hbeta      13.63       1.2     -12    29
# Comp:  1                Halpha      40.29       1.2     -12    29
# Comp:  2             [SII]6716      6.607       1.2     -11    31
# Comp:  2             [SII]6731      4.392       1.2     -11    31
# Comp:  2              HeII4687     0.1555       1.2     -11    31
# Comp:  2               HeI5876     0.7269       1.2     -11    31
# Comp:  2          [OIII]5007_d      16.18       1.6     -11    31
# Comp:  2            [OI]6300_d      1.506       1.6     -11    31
# Comp:  2           [NII]6583_d      8.896       1.6     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -15        31
#  comp.  2:        -9        27
# chi2/DOF: 1.067; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.231       1.2     -15    31
# Comp:  1                 Hbeta      15.57       1.2     -15    31
# Comp:  1                Halpha      41.23       1.2     -15    31
# Comp:  2             [SII]6716      7.346       1.2      -9    27
# Comp:  2             [SII]6731      4.507       1.2      -9    27
# Comp:  2              HeII4687     0.4743       1.2      -9    27
# Comp:  2               HeI5876     0.7040       1.2      -9    27
# Comp:  2          [OIII]5007_d      17.43       1.5      -9    27
# Comp:  2            [OI]6300_d     0.4249       1.5      -9    27
# Comp:  2           [NII]6583_d      8.766       1.5      -9    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        34
#  comp.  1:       -12        29
#  comp.  2:       -11        31
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.656       1.2     -12    29
# Comp:  1                 Hbeta      16.60       1.2     -12    29
# Comp:  1                Halpha      41.12       1.2     -12    29
# Comp:  2             [SII]6716      7.687       1.2     -11    31
# Comp:  2             [SII]6731      4.737       1.2     -11    31
# Comp:  2              HeII4687     0.4305       1.2     -11    31
# Comp:  2               HeI5876      1.070       1.2     -11    31
# Comp:  2          [OIII]5007_d      16.83       1.6     -11    31
# Comp:  2            [OI]6300_d      2.005       1.6     -11    31
# Comp:  2           [NII]6583_d      9.506       1.6     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        23
#  comp.  1:       -12        29
#  comp.  2:       -10        32
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.521       1.2     -12    29
# Comp:  1                 Hbeta      14.63       1.2     -12    29
# Comp:  1                Halpha      39.32       1.2     -12    29
# Comp:  2             [SII]6716      6.443       1.2     -10    32
# Comp:  2             [SII]6731      4.581       1.2     -10    32
# Comp:  2              HeII4687     0.7060       1.2     -10    32
# Comp:  2               HeI5876      1.187       1.2     -10    32
# Comp:  2          [OIII]5007_d      15.25       1.6     -10    32
# Comp:  2            [OI]6300_d      2.335       1.6     -10    32
# Comp:  2           [NII]6583_d      9.523       1.6     -10    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        31
#  comp.  1:       -13        28
#  comp.  2:       -11        32
# chi2/DOF: 1.069; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.922       1.2     -13    28
# Comp:  1                 Hbeta      14.50       1.2     -13    28
# Comp:  1                Halpha      40.73       1.2     -13    28
# Comp:  2             [SII]6716      6.518       1.2     -11    32
# Comp:  2             [SII]6731      4.390       1.2     -11    32
# Comp:  2              HeII4687     0.3250       1.2     -11    32
# Comp:  2               HeI5876     0.6172       1.2     -11    32
# Comp:  2          [OIII]5007_d      15.42       1.6     -11    32
# Comp:  2            [OI]6300_d      1.845       1.6     -11    32
# Comp:  2           [NII]6583_d      9.604       1.6     -11    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -16        33
#  comp.  2:       -12        24
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.779       1.2     -16    33
# Comp:  1                 Hbeta      13.47       1.2     -16    33
# Comp:  1                Halpha      40.60       1.2     -16    33
# Comp:  2             [SII]6716      7.489       1.2     -12    24
# Comp:  2             [SII]6731      4.400       1.2     -12    24
# Comp:  2              HeII4687     0.7684       1.2     -12    24
# Comp:  2               HeI5876      1.011       1.2     -12    24
# Comp:  2          [OIII]5007_d      15.68       1.5     -12    24
# Comp:  2            [OI]6300_d     0.3509       1.5     -12    24
# Comp:  2           [NII]6583_d      10.44       1.5     -12    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        63
#  comp.  1:       -10        24
#  comp.  2:       -13        19
# chi2/DOF: 1.059; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.522       1.2     -10    24
# Comp:  1                 Hbeta      14.01       1.2     -10    24
# Comp:  1                Halpha      39.17       1.2     -10    24
# Comp:  2             [SII]6716      6.500       1.2     -13    19
# Comp:  2             [SII]6731      4.358       1.2     -13    19
# Comp:  2              HeII4687     0.5448       1.2     -13    19
# Comp:  2               HeI5876      1.085       1.2     -13    19
# Comp:  2          [OIII]5007_d      15.26       1.5     -13    19
# Comp:  2            [OI]6300_d      1.568       1.5     -13    19
# Comp:  2           [NII]6583_d      9.602       1.5     -13    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6         1
#  comp.  1:       -10        23
#  comp.  2:        -9        29
# chi2/DOF: 1.069; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.886       1.2     -10    23
# Comp:  1                 Hbeta      15.13       1.2     -10    23
# Comp:  1                Halpha      39.47       1.2     -10    23
# Comp:  2             [SII]6716      7.633       1.2      -9    29
# Comp:  2             [SII]6731      4.627       1.2      -9    29
# Comp:  2              HeII4687     0.5728       1.2      -9    29
# Comp:  2               HeI5876      1.089       1.2      -9    29
# Comp:  2          [OIII]5007_d      15.32       1.5      -9    29
# Comp:  2            [OI]6300_d      1.078       1.5      -9    29
# Comp:  2           [NII]6583_d      8.921       1.5      -9    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        -9        30
#  comp.  2:        -7        28
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.258       1.2      -9    30
# Comp:  1                 Hbeta      13.97       1.2      -9    30
# Comp:  1                Halpha      40.14       1.2      -9    30
# Comp:  2             [SII]6716      7.311       1.2      -7    28
# Comp:  2             [SII]6731      4.175       1.2      -7    28
# Comp:  2              HeII4687     0.1955       1.2      -7    28
# Comp:  2               HeI5876      1.022       1.2      -7    28
# Comp:  2          [OIII]5007_d      17.52       1.5      -7    28
# Comp:  2            [OI]6300_d     0.9703       1.5      -7    28
# Comp:  2           [NII]6583_d      8.929       1.5      -7    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        75
#  comp.  1:       -12        29
#  comp.  2:       -10        31
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.844       1.2     -12    29
# Comp:  1                 Hbeta      14.97       1.2     -12    29
# Comp:  1                Halpha      39.12       1.2     -12    29
# Comp:  2             [SII]6716      6.581       1.2     -10    31
# Comp:  2             [SII]6731      4.608       1.2     -10    31
# Comp:  2              HeII4687     0.6635       1.2     -10    31
# Comp:  2               HeI5876      1.050       1.2     -10    31
# Comp:  2          [OIII]5007_d      16.21       1.6     -10    31
# Comp:  2            [OI]6300_d      1.430       1.6     -10    31
# Comp:  2           [NII]6583_d      9.162       1.6     -10    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -13        36
#  comp.  2:       -14        37
# chi2/DOF: 1.061; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.148       1.2     -13    36
# Comp:  1                 Hbeta      14.11       1.2     -13    36
# Comp:  1                Halpha      40.41       1.2     -13    36
# Comp:  2             [SII]6716      6.962       1.2     -14    37
# Comp:  2             [SII]6731      4.262       1.2     -14    37
# Comp:  2              HeII4687     0.5011       1.2     -14    37
# Comp:  2               HeI5876     0.8216       1.2     -14    37
# Comp:  2          [OIII]5007_d      16.34       1.6     -14    37
# Comp:  2            [OI]6300_d     0.5422       1.6     -14    37
# Comp:  2           [NII]6583_d      8.117       1.6     -14    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -13        30
#  comp.  2:        -7        40
# chi2/DOF: 1.069; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.598       1.2     -13    30
# Comp:  1                 Hbeta      13.02       1.2     -13    30
# Comp:  1                Halpha      40.15       1.2     -13    30
# Comp:  2             [SII]6716      7.524       1.3      -7    40
# Comp:  2             [SII]6731      4.849       1.3      -7    40
# Comp:  2              HeII4687     0.4356       1.3      -7    40
# Comp:  2               HeI5876      1.204       1.3      -7    40
# Comp:  2          [OIII]5007_d      16.19       1.6      -7    40
# Comp:  2            [OI]6300_d      1.634       1.6      -7    40
# Comp:  2           [NII]6583_d      9.845       1.6      -7    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -16        34
#  comp.  2:        -3        41
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.202       1.2     -16    34
# Comp:  1                 Hbeta      15.78       1.2     -16    34
# Comp:  1                Halpha      40.48       1.2     -16    34
# Comp:  2             [SII]6716      8.174       1.3      -3    41
# Comp:  2             [SII]6731      4.879       1.3      -3    41
# Comp:  2              HeII4687     0.2772       1.3      -3    41
# Comp:  2               HeI5876      1.203       1.3      -3    41
# Comp:  2          [OIII]5007_d      15.88       1.6      -3    41
# Comp:  2            [OI]6300_d      1.903       1.6      -3    41
# Comp:  2           [NII]6583_d      10.74       1.6      -3    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -13        32
#  comp.  2:        -8        27
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.613       1.2     -13    32
# Comp:  1                 Hbeta      13.34       1.2     -13    32
# Comp:  1                Halpha      40.55       1.2     -13    32
# Comp:  2             [SII]6716      7.689       1.2      -8    27
# Comp:  2             [SII]6731      4.419       1.2      -8    27
# Comp:  2              HeII4687     0.2386       1.2      -8    27
# Comp:  2               HeI5876     0.9761       1.2      -8    27
# Comp:  2          [OIII]5007_d      14.84       1.5      -8    27
# Comp:  2            [OI]6300_d      1.143       1.5      -8    27
# Comp:  2           [NII]6583_d      8.815       1.5      -8    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -11        27
#  comp.  2:        -7        36
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.597       1.2     -11    27
# Comp:  1                 Hbeta      14.67       1.2     -11    27
# Comp:  1                Halpha      39.24       1.2     -11    27
# Comp:  2             [SII]6716      7.633       1.2      -7    36
# Comp:  2             [SII]6731      4.102       1.2      -7    36
# Comp:  2              HeII4687     0.4676       1.2      -7    36
# Comp:  2               HeI5876     0.6932       1.2      -7    36
# Comp:  2          [OIII]5007_d      14.43       1.6      -7    36
# Comp:  2            [OI]6300_d      0.000       1.6      -7    36
# Comp:  2           [NII]6583_d      8.951       1.6      -7    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -15        32
#  comp.  2:        -5        29
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.111       1.2     -15    32
# Comp:  1                 Hbeta      15.91       1.2     -15    32
# Comp:  1                Halpha      41.09       1.2     -15    32
# Comp:  2             [SII]6716      7.609       1.2      -5    29
# Comp:  2             [SII]6731      4.969       1.2      -5    29
# Comp:  2              HeII4687     0.6479       1.2      -5    29
# Comp:  2               HeI5876      1.148       1.2      -5    29
# Comp:  2          [OIII]5007_d      16.39       1.5      -5    29
# Comp:  2            [OI]6300_d      1.232       1.5      -5    29
# Comp:  2           [NII]6583_d      9.650       1.5      -5    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -10        30
#  comp.  2:        -9        30
# chi2/DOF: 1.062; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.328       1.2     -10    30
# Comp:  1                 Hbeta      13.37       1.2     -10    30
# Comp:  1                Halpha      40.01       1.2     -10    30
# Comp:  2             [SII]6716      6.737       1.2      -9    30
# Comp:  2             [SII]6731      4.313       1.2      -9    30
# Comp:  2              HeII4687     0.4504       1.2      -9    30
# Comp:  2               HeI5876     0.8931       1.2      -9    30
# Comp:  2          [OIII]5007_d      17.53       1.5      -9    30
# Comp:  2            [OI]6300_d      1.471       1.5      -9    30
# Comp:  2           [NII]6583_d      9.277       1.5      -9    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12         6
#  comp.  1:       -11        28
#  comp.  2:       -16        45
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.777       1.2     -11    28
# Comp:  1                 Hbeta      15.92       1.2     -11    28
# Comp:  1                Halpha      39.64       1.2     -11    28
# Comp:  2             [SII]6716      7.025       1.3     -16    45
# Comp:  2             [SII]6731      4.991       1.3     -16    45
# Comp:  2              HeII4687     0.4562       1.3     -16    45
# Comp:  2               HeI5876      1.107       1.3     -16    45
# Comp:  2          [OIII]5007_d      16.48       1.6     -16    45
# Comp:  2            [OI]6300_d      1.965       1.6     -16    45
# Comp:  2           [NII]6583_d      10.63       1.6     -16    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -12        44
#  comp.  2:        -8        37
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.009       1.3     -12    44
# Comp:  1                 Hbeta      14.18       1.3     -12    44
# Comp:  1                Halpha      42.04       1.3     -12    44
# Comp:  2             [SII]6716      8.330       1.3      -8    37
# Comp:  2             [SII]6731      4.903       1.3      -8    37
# Comp:  2              HeII4687     0.4620       1.3      -8    37
# Comp:  2               HeI5876      1.401       1.3      -8    37
# Comp:  2          [OIII]5007_d      16.17       1.6      -8    37
# Comp:  2            [OI]6300_d      1.898       1.6      -8    37
# Comp:  2           [NII]6583_d      10.11       1.6      -8    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        48
#  comp.  1:       -12        28
#  comp.  2:       -11        31
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.883       1.2     -12    28
# Comp:  1                 Hbeta      17.08       1.2     -12    28
# Comp:  1                Halpha      41.16       1.2     -12    28
# Comp:  2             [SII]6716      6.933       1.2     -11    31
# Comp:  2             [SII]6731      4.411       1.2     -11    31
# Comp:  2              HeII4687     0.2186       1.2     -11    31
# Comp:  2               HeI5876     0.7388       1.2     -11    31
# Comp:  2          [OIII]5007_d      14.16       1.6     -11    31
# Comp:  2            [OI]6300_d      1.234       1.6     -11    31
# Comp:  2           [NII]6583_d      7.905       1.6     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        19
#  comp.  1:       -15        31
#  comp.  2:       -15        21
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.042       1.2     -15    31
# Comp:  1                 Hbeta      15.17       1.2     -15    31
# Comp:  1                Halpha      39.53       1.2     -15    31
# Comp:  2             [SII]6716      7.299       1.2     -15    21
# Comp:  2             [SII]6731      4.189       1.2     -15    21
# Comp:  2              HeII4687     0.4842       1.2     -15    21
# Comp:  2               HeI5876      1.074       1.2     -15    21
# Comp:  2          [OIII]5007_d      15.00       1.5     -15    21
# Comp:  2            [OI]6300_d     0.2815       1.5     -15    21
# Comp:  2           [NII]6583_d      9.239       1.5     -15    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -12        26
#  comp.  2:       -13        19
# chi2/DOF: 1.068; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.444       1.2     -12    26
# Comp:  1                 Hbeta      13.09       1.2     -12    26
# Comp:  1                Halpha      38.54       1.2     -12    26
# Comp:  2             [SII]6716      6.297       1.2     -13    19
# Comp:  2             [SII]6731      4.433       1.2     -13    19
# Comp:  2              HeII4687     0.2225       1.2     -13    19
# Comp:  2               HeI5876      1.245       1.2     -13    19
# Comp:  2          [OIII]5007_d      15.00       1.5     -13    19
# Comp:  2            [OI]6300_d      1.306       1.5     -13    19
# Comp:  2           [NII]6583_d      8.565       1.5     -13    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        41
#  comp.  1:       -12        27
#  comp.  2:       -14        25
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.592       1.2     -12    27
# Comp:  1                 Hbeta      15.66       1.2     -12    27
# Comp:  1                Halpha      39.70       1.2     -12    27
# Comp:  2             [SII]6716      7.819       1.2     -14    25
# Comp:  2             [SII]6731      4.373       1.2     -14    25
# Comp:  2              HeII4687     0.5123       1.2     -14    25
# Comp:  2               HeI5876     0.6568       1.2     -14    25
# Comp:  2          [OIII]5007_d      16.17       1.5     -14    25
# Comp:  2            [OI]6300_d      1.225       1.5     -14    25
# Comp:  2           [NII]6583_d      8.954       1.5     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -12        28
#  comp.  2:       -11        31
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.589       1.2     -12    28
# Comp:  1                 Hbeta      12.78       1.2     -12    28
# Comp:  1                Halpha      40.22       1.2     -12    28
# Comp:  2             [SII]6716      6.794       1.2     -11    31
# Comp:  2             [SII]6731      4.719       1.2     -11    31
# Comp:  2              HeII4687     0.8582       1.2     -11    31
# Comp:  2               HeI5876      1.488       1.2     -11    31
# Comp:  2          [OIII]5007_d      14.35       1.6     -11    31
# Comp:  2            [OI]6300_d      0.000       1.6     -11    31
# Comp:  2           [NII]6583_d      8.308       1.6     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        62
#  comp.  1:       -13        29
#  comp.  2:       -10        30
# chi2/DOF: 1.063; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.734       1.2     -13    29
# Comp:  1                 Hbeta      16.25       1.2     -13    29
# Comp:  1                Halpha      40.72       1.2     -13    29
# Comp:  2             [SII]6716      7.107       1.2     -10    30
# Comp:  2             [SII]6731      4.457       1.2     -10    30
# Comp:  2              HeII4687     0.3398       1.2     -10    30
# Comp:  2               HeI5876      1.325       1.2     -10    30
# Comp:  2          [OIII]5007_d      17.27       1.5     -10    30
# Comp:  2            [OI]6300_d     0.6553       1.5     -10    30
# Comp:  2           [NII]6583_d      7.888       1.5     -10    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        73
#  comp.  1:       -11        19
#  comp.  2:       -10        34
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.543       1.2     -11    19
# Comp:  1                 Hbeta      14.11       1.2     -11    19
# Comp:  1                Halpha      37.55       1.2     -11    19
# Comp:  2             [SII]6716      7.379       1.2     -10    34
# Comp:  2             [SII]6731      4.757       1.2     -10    34
# Comp:  2              HeII4687     0.3824       1.2     -10    34
# Comp:  2               HeI5876      1.095       1.2     -10    34
# Comp:  2          [OIII]5007_d      14.89       1.6     -10    34
# Comp:  2            [OI]6300_d      1.452       1.6     -10    34
# Comp:  2           [NII]6583_d      9.713       1.6     -10    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       737
#  comp.  1:        -8        15
#  comp.  2:        -8        33
# chi2/DOF: 1.057; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.775       1.2      -8    15
# Comp:  1                 Hbeta      11.44       1.2      -8    15
# Comp:  1                Halpha      36.46       1.2      -8    15
# Comp:  2             [SII]6716      6.953       1.2      -8    33
# Comp:  2             [SII]6731      4.768       1.2      -8    33
# Comp:  2              HeII4687     0.6259       1.2      -8    33
# Comp:  2               HeI5876      1.845       1.2      -8    33
# Comp:  2          [OIII]5007_d      17.63       1.6      -8    33
# Comp:  2            [OI]6300_d      0.000       1.6      -8    33
# Comp:  2           [NII]6583_d      8.513       1.6      -8    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -12        30
#  comp.  2:       -11        30
# chi2/DOF: 1.063; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.610       1.2     -12    30
# Comp:  1                 Hbeta      13.36       1.2     -12    30
# Comp:  1                Halpha      39.66       1.2     -12    30
# Comp:  2             [SII]6716      7.410       1.2     -11    30
# Comp:  2             [SII]6731      4.590       1.2     -11    30
# Comp:  2              HeII4687    0.03373       1.2     -11    30
# Comp:  2               HeI5876      1.312       1.2     -11    30
# Comp:  2          [OIII]5007_d      15.90       1.5     -11    30
# Comp:  2            [OI]6300_d      2.615       1.5     -11    30
# Comp:  2           [NII]6583_d      10.42       1.5     -11    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        21
#  comp.  1:       -14        30
#  comp.  2:       -17        31
# chi2/DOF: 1.067; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.867       1.2     -14    30
# Comp:  1                 Hbeta      13.42       1.2     -14    30
# Comp:  1                Halpha      39.46       1.2     -14    30
# Comp:  2             [SII]6716      6.684       1.2     -17    31
# Comp:  2             [SII]6731      4.317       1.2     -17    31
# Comp:  2              HeII4687     0.5967       1.2     -17    31
# Comp:  2               HeI5876     0.7463       1.2     -17    31
# Comp:  2          [OIII]5007_d      17.01       1.6     -17    31
# Comp:  2            [OI]6300_d     0.7853       1.6     -17    31
# Comp:  2           [NII]6583_d      8.601       1.6     -17    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8         1
#  comp.  1:       -12        26
#  comp.  2:       -20        28
# chi2/DOF: 1.069; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.740       1.2     -12    26
# Comp:  1                 Hbeta      15.28       1.2     -12    26
# Comp:  1                Halpha      39.94       1.2     -12    26
# Comp:  2             [SII]6716      7.189       1.2     -20    28
# Comp:  2             [SII]6731      4.291       1.2     -20    28
# Comp:  2              HeII4687     0.4669       1.2     -20    28
# Comp:  2               HeI5876      1.209       1.2     -20    28
# Comp:  2          [OIII]5007_d      17.10       1.5     -20    28
# Comp:  2            [OI]6300_d      1.582       1.5     -20    28
# Comp:  2           [NII]6583_d      9.317       1.5     -20    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15        35
#  comp.  1:        -9        33
#  comp.  2:       -11        25
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.105       1.2      -9    33
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        62
#  comp.  1:       -12        28
#  comp.  2:       -11        31
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.168       1.2     -12    28
# Comp:  1                 Hbeta      13.13       1.2     -12    28
# Comp:  1                Halpha      38.69       1.2     -12    28
# Comp:  2             [SII]6716      7.725       1.2     -11    31
# Comp:  2             [SII]6731      4.779       1.2     -11    31
# Comp:  2              HeII4687     0.4824       1.2     -11    31
# Comp:  2               HeI5876     0.8513       1.2     -11    31
# Comp:  2          [OIII]5007_d      14.46       1.6     -11    31
# Comp:  2            [OI]6300_d      1.951       1.6     -11    31
# Comp:  2           [NII]6583_d      9.000       1.6     -11    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:       -13        19
#  comp.  2:        -7        26
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.474       1.2     -13    19
# Comp:  1                 Hbeta      13.79       1.2     -13    19
# Comp:  1                Halpha      39.40       1.2     -13    19
# Comp:  2             [SII]6716      7.497       1.2      -7    26
# Comp:  2             [SII]6731      4.368       1.2      -7    26
# Comp:  2              HeII4687     0.4881       1.2      -7    26
# Comp:  2               HeI5876      1.314       1.2      -7    26
# Comp:  2          [OIII]5007_d      16.40       1.5      -7    26
# Comp:  2            [OI]6300_d     0.5158       1.5      -7    26
# Comp:  2           [NII]6583_d      8.624       1.5      -7    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        61
#  comp.  1:       -11        32
#  comp.  2:        -9        16
# chi2/DOF: 1.062; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.603       1.2     -11    32
# Comp:  1                 Hbeta      16.36       1.2     -11    32
# Comp:  1                Halpha      41.15       1.2     -11    32
# Comp:  2             [SII]6716      7.487       1.2      -9    16
# Comp:  2             [SII]6731      4.250       1.2      -9    16
# Comp:  2              HeII4687     0.5515       1.2      -9    16
# Comp:  2               HeI5876     0.7737       1.2      -9    16
# Comp:  2          [OIII]5007_d      14.69       1.5      -9    16
# Comp:  2            [OI]6300_d      1.965       1.5      -9    16
# Comp:  2           [NII]6583_d      9.867       1.5      -9    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -15        35
#  comp.  2:       -14        18
# chi2/DOF: 1.067; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.182       1.2     -15    35
# Comp:  1                 Hbeta      13.47       1.2     -15    35
# Comp:  1                Halpha      40.79       1.2     -15    35
# Comp:  2             [SII]6716      6.340       1.2     -14    18
# Comp:  2             [SII]6731      4.208       1.2     -14    18
# Comp:  2              HeII4687     0.3784       1.2     -14    18
# Comp:  2               HeI5876     0.7093       1.2     -14    18
# Comp:  2          [OIII]5007_d      16.03       1.5     -14    18
# Comp:  2            [OI]6300_d     0.7310       1.5     -14    18
# Comp:  2           [NII]6583_d      8.752       1.5     -14    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -10        24
#  comp.  2:       -10        24
# chi2/DOF: 1.067; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.829       1.2     -10    24
# Comp:  1                 Hbeta      16.02       1.2     -10    24
# Comp:  1                Halpha      39.49       1.2     -10    24
# Comp:  2             [SII]6716      7.028       1.2     -10    24
# Comp:  2             [SII]6731      4.459       1.2     -10    24
# Comp:  2              HeII4687     0.2982       1.2     -10    24
# Comp:  2               HeI5876      1.101       1.2     -10    24
# Comp:  2          [OIII]5007_d      13.82       1.5     -10    24
# Comp:  2            [OI]6300_d      1.049       1.5     -10    24
# Comp:  2           [NII]6583_d      9.028       1.5     -10    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20        53
#  comp.  1:        -8        25
#  comp.  2:        -4        33
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.065       1.2      -8    25
# Comp:  1                 Hbeta      12.41       1.2      -8    25
# Comp:  1                Halpha      38.88       1.2      -8    25
# Comp:  2             [SII]6716      6.370       1.2      -4    33
# Comp:  2             [SII]6731      4.807       1.2      -4    33
# Comp:  2              HeII4687     0.6518       1.2      -4    33
# Comp:  2               HeI5876     0.7295       1.2      -4    33
# Comp:  2          [OIII]5007_d      15.42       1.6      -4    33
# Comp:  2            [OI]6300_d     0.3428       1.6      -4    33
# Comp:  2           [NII]6583_d      8.630       1.6      -4    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40       127
#  comp.  1:       -11        33
#  comp.  2:        -1        42
# chi2/DOF: 1.062; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.766       1.2     -11    33
# Comp:  1                 Hbeta      15.08       1.2     -11    33
# Comp:  1                Halpha      38.72       1.2     -11    33
# Comp:  2             [SII]6716      7.396       1.3      -1    42
# Comp:  2             [SII]6731      4.383       1.3      -1    42
# Comp:  2              HeII4687     0.9180       1.3      -1    42
# Comp:  2               HeI5876     0.8445       1.3      -1    42
# Comp:  2          [OIII]5007_d      15.50       1.6      -1    42
# Comp:  2            [OI]6300_d      0.000       1.6      -1    42
# Comp:  2           [NII]6583_d      9.120       1.6      -1    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -14        28
#  comp.  2:        -9        44
# chi2/DOF: 1.068; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.244       1.2     -14    28
# Comp:  1                 Hbeta      15.03       1.2     -14    28
# Comp:  1                Halpha      39.91       1.2     -14    28
# Comp:  2             [SII]6716      7.868       1.3      -9    44
# Comp:  2             [SII]6731      5.328       1.3      -9    44
# Comp:  2              HeII4687     0.6890       1.3      -9    44
# Comp:  2               HeI5876     0.9989       1.3      -9    44
# Comp:  2          [OIII]5007_d      17.08       1.6      -9    44
# Comp:  2            [OI]6300_d      1.153       1.6      -9    44
# Comp:  2           [NII]6583_d      9.344       1.6      -9    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        75
#  comp.  1:       -16        34
#  comp.  2:       -12        34
# chi2/DOF: 1.065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.729       1.2     -16    34
# Comp:  1                 Hbeta      13.13       1.2     -16    34
# Comp:  1                Halpha      39.71       1.2     -16    34
# Comp:  2             [SII]6716      7.106       1.2     -12    34
# Comp:  2             [SII]6731      4.972       1.2     -12    34
# Comp:  2              HeII4687     0.6814       1.2     -12    34
# Comp:  2               HeI5876      1.704       1.2     -12    34
# Comp:  2          [OIII]5007_d      17.64       1.6     -12    34
# Comp:  2            [OI]6300_d     0.1007       1.6     -12    34
# Comp:  2           [NII]6583_d      8.448       1.6     -12    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -14        31
#  comp.  2:       -14        33
# chi2/DOF: 1.069; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.305       1.2     -14    31
# Comp:  1                 Hbeta      13.25       1.2     -14    31
# Comp:  1                Halpha      39.85       1.2     -14    31
# Comp:  2             [SII]6716      7.462       1.2     -14    33
# Comp:  2             [SII]6731      4.196       1.2     -14    33
# Comp:  2              HeII4687     0.3423       1.2     -14    33
# Comp:  2               HeI5876     0.9549       1.2     -14    33
# Comp:  2          [OIII]5007_d      16.78       1.6     -14    33
# Comp:  2            [OI]6300_d      1.979       1.6     -14    33
# Comp:  2           [NII]6583_d      8.860       1.6     -14    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        73
#  comp.  1:       -10        38
#  comp.  2:       -18        24
# chi2/DOF: 1.064; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.668       1.3     -10    38
# Comp:  1                 Hbeta      13.44       1.3     -10    38
# Comp:  1                Halpha      41.80       1.3     -10    38
# Comp:  2             [SII]6716      6.653       1.2     -18    24
# Comp:  2             [SII]6731      4.201       1.2     -18    24
# Comp:  2              HeII4687     0.5408       1.2     -18    24
# Comp:  2               HeI5876     0.7962       1.2     -18    24
# Comp:  2          [OIII]5007_d      16.84       1.5     -18    24
# Comp:  2            [OI]6300_d     0.6707       1.5     -18    24
# Comp:  2           [NII]6583_d      9.182       1.5     -18    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -13        15
#  comp.  2:       -14        24
# chi2/DOF: 1.066; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.176       1.2     -13    15
# Comp:  1                 Hbeta      14.59       1.2     -13    15
# Comp:  1                Halpha      38.40       1.2     -13    15
# Comp:  2             [SII]6716      6.634       1.2     -14    24
# Comp:  2             [SII]6731      4.604       1.2     -14    24
# Comp:  2              HeII4687     0.7768       1.2     -14    24
# Comp:  2               HeI5876      1.035       1.2     -14    24
# Comp:  2          [OIII]5007_d      14.61       1.5     -14    24
# Comp:  2            [OI]6300_d      1.302       1.5     -14    24
# Comp:  2           [NII]6583_d      9.280       1.5     -14    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:       -11        32
#  comp.  2:       -10        14
# chi2/DOF: 1.059; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.168       1.2     -11    32
# Comp:  1                 Hbeta      15.24       1.2     -11    32
# Comp:  1                Halpha      38.87       1.2     -11    32
# Comp:  2             [SII]6716      7.147       1.2     -10    14
# Comp:  2             [SII]6731      4.276       1.2     -10    14
# Comp:  2              HeII4687     0.7416       1.2     -10    14
# Comp:  2               HeI5876     0.6024       1.2     -10    14
# Comp:  2          [OIII]5007_d      14.73       1.5     -10    14
# Comp:  2            [OI]6300_d      1.267       1.5     -10    14
# Comp:  2           [NII]6583_d      8.658       1.5     -10    14
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.33903439, 1.35197497, 1.6029859 , 0.72655597, 0.38950267,
#        0.21049437, 0.37776269, 1.09802295, 0.92247212, 0.99159039])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 5.71257184, 14.39546693, 54.16350097, 10.05108442,  6.34259239,
#         0.44570819,  1.31744953, 16.66870012,  1.46848636, 12.72806381])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_5_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_5_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_5_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_5_noreg_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.077035    0.018057
# 1         Hbeta  0.194125    0.018232
# 2        Halpha  0.730403    0.021616
# 3     [SII]6716  0.135540    0.009798
# 4     [SII]6731  0.085531    0.005253
# 5      HeII4687  0.006010    0.002839
# 6       HeI5876  0.017766    0.005094
# 7  [OIII]5007_d  0.224780    0.014807
# 8    [OI]6300_d  0.019803    0.012440
# 9   [NII]6583_d  0.171640    0.013372
#           Name      Flux  Error_flux
# 0       Hgamma  0.077035    0.018057
# 1        Hbeta  0.194125    0.018232
# 2       Halpha  0.730403    0.021616
# 3    [SII]6716  0.135540    0.009798
# 4    [SII]6731  0.085531    0.005253
# 5     HeII4687  0.006010    0.002839
# 6      HeI5876  0.017766    0.005094
# 7   [OIII]4959  0.056195    0.014807
# 8   [OIII]5007  0.168585    0.014807
# 9     [OI]6300  0.014852    0.012440
# 10    [OI]6364  0.004951    0.012440
# 11   [NII]6548  0.042910    0.013372
# 12   [NII]6583  0.128730    0.013372

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01348514621072994
