# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_11.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.01736
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_24ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_11']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4227.35314933 4228.80789494 4230.26264056 ... 6972.45812692 6973.91287253
#  6975.36761815] [0.16503506 0.15484369 0.13583273 ... 0.11934165 0.13194976 0.12332551] [0.01322568 0.01322568 0.01322568 ... 0.01322568 0.01322568 0.01322568]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11367657 2.11440395 2.11513132 ... 3.48622906 3.48695644 3.48768381]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3337, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.52964314399512

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3337, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        54
# chi2/DOF: 0.005352; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        46
# chi2/DOF: 0.002787; DOF: 2042; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-29.64492851,  45.92005871])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        64
#  comp.  1:       -51        32
#  comp.  2:       -58        41
# chi2/DOF: 0.5923; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.595      0.19     -51    32
# Comp:  1                 Hbeta      3.258      0.19     -51    32
# Comp:  1                Halpha      12.42      0.19     -51    32
# Comp:  2             [SII]6716      3.561      0.19     -58    41
# Comp:  2             [SII]6731      2.458      0.19     -58    41
# Comp:  2              HeII4687      0.000      0.19     -58    41
# Comp:  2               HeI5876     0.1016      0.19     -58    41
# Comp:  2          [OIII]5007_d      3.292      0.25     -58    41
# Comp:  2            [OI]6300_d     0.7195      0.25     -58    41
# Comp:  2           [NII]6583_d      5.419      0.25     -58    41
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  9.875; gas flux:      1 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:   18.8; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  74.85; gas flux:     17 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  20.83; gas flux:      5 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  13.81; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.5946; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  14.26; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.967; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  23.51; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        46
#  comp.  1:       -51        32
#  comp.  2:       -57        40
# chi2/DOF: 0.5865; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.005      0.19     -51    32
# Comp:  1                 Hbeta      3.434      0.19     -51    32
# Comp:  1                Halpha      12.51      0.19     -51    32
# Comp:  2             [SII]6716      3.430      0.19     -57    40
# Comp:  2             [SII]6731      2.352      0.19     -57    40
# Comp:  2              HeII4687     0.1014      0.19     -57    40
# Comp:  2               HeI5876    0.09624      0.19     -57    40
# Comp:  2          [OIII]5007_d      3.231      0.24     -57    40
# Comp:  2            [OI]6300_d     0.7016      0.24     -57    40
# Comp:  2           [NII]6583_d      5.426      0.24     -57    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        34
#  comp.  1:       -49        32
#  comp.  2:       -58        46
# chi2/DOF: 0.5860; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.888      0.19     -49    32
# Comp:  1                 Hbeta      3.509      0.19     -49    32
# Comp:  1                Halpha      12.48      0.19     -49    32
# Comp:  2             [SII]6716      3.555      0.20     -58    46
# Comp:  2             [SII]6731      2.486      0.20     -58    46
# Comp:  2              HeII4687      0.000      0.20     -58    46
# Comp:  2               HeI5876    0.02572      0.20     -58    46
# Comp:  2          [OIII]5007_d      3.195      0.25     -58    46
# Comp:  2            [OI]6300_d     0.8099      0.25     -58    46
# Comp:  2           [NII]6583_d      5.625      0.25     -58    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        66
#  comp.  1:       -52        34
#  comp.  2:       -58        39
# chi2/DOF: 0.5888; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.655      0.19     -52    34
# Comp:  1                 Hbeta      3.493      0.19     -52    34
# Comp:  1                Halpha      12.66      0.19     -52    34
# Comp:  2             [SII]6716      3.486      0.19     -58    39
# Comp:  2             [SII]6731      2.426      0.19     -58    39
# Comp:  2              HeII4687      0.000      0.19     -58    39
# Comp:  2               HeI5876     0.1174      0.19     -58    39
# Comp:  2          [OIII]5007_d      3.341      0.24     -58    39
# Comp:  2            [OI]6300_d     0.7458      0.24     -58    39
# Comp:  2           [NII]6583_d      5.423      0.24     -58    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        71
#  comp.  1:       -53        29
#  comp.  2:       -59        33
# chi2/DOF: 0.5880; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.440      0.19     -53    29
# Comp:  1                 Hbeta      2.979      0.19     -53    29
# Comp:  1                Halpha      12.36      0.19     -53    29
# Comp:  2             [SII]6716      3.448      0.19     -59    33
# Comp:  2             [SII]6731      2.434      0.19     -59    33
# Comp:  2              HeII4687      0.000      0.19     -59    33
# Comp:  2               HeI5876    0.06463      0.19     -59    33
# Comp:  2          [OIII]5007_d      3.269      0.24     -59    33
# Comp:  2            [OI]6300_d     0.6130      0.24     -59    33
# Comp:  2           [NII]6583_d      5.280      0.24     -59    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        83
#  comp.  1:       -53        37
#  comp.  2:       -56        39
# chi2/DOF: 0.5845; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.865      0.19     -53    37
# Comp:  1                 Hbeta      3.127      0.19     -53    37
# Comp:  1                Halpha      12.68      0.19     -53    37
# Comp:  2             [SII]6716      3.489      0.19     -56    39
# Comp:  2             [SII]6731      2.378      0.19     -56    39
# Comp:  2              HeII4687      0.000      0.19     -56    39
# Comp:  2               HeI5876     0.1058      0.19     -56    39
# Comp:  2          [OIII]5007_d      3.046      0.24     -56    39
# Comp:  2            [OI]6300_d     0.6334      0.24     -56    39
# Comp:  2           [NII]6583_d      5.269      0.24     -56    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        74
#  comp.  1:       -51        33
#  comp.  2:       -59        42
# chi2/DOF: 0.5865; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.718      0.19     -51    33
# Comp:  1                 Hbeta      3.516      0.19     -51    33
# Comp:  1                Halpha      12.58      0.19     -51    33
# Comp:  2             [SII]6716      3.520      0.20     -59    42
# Comp:  2             [SII]6731      2.443      0.20     -59    42
# Comp:  2              HeII4687      0.000      0.20     -59    42
# Comp:  2               HeI5876    0.03179      0.20     -59    42
# Comp:  2          [OIII]5007_d      3.167      0.25     -59    42
# Comp:  2            [OI]6300_d     0.6929      0.25     -59    42
# Comp:  2           [NII]6583_d      5.487      0.25     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        62
#  comp.  1:       -52        28
#  comp.  2:       -56        43
# chi2/DOF: 0.5878; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.732      0.19     -52    28
# Comp:  1                 Hbeta      3.250      0.19     -52    28
# Comp:  1                Halpha      12.30      0.19     -52    28
# Comp:  2             [SII]6716      3.534      0.20     -56    43
# Comp:  2             [SII]6731      2.373      0.20     -56    43
# Comp:  2              HeII4687      0.000      0.20     -56    43
# Comp:  2               HeI5876     0.1332      0.20     -56    43
# Comp:  2          [OIII]5007_d      3.314      0.25     -56    43
# Comp:  2            [OI]6300_d     0.8340      0.25     -56    43
# Comp:  2           [NII]6583_d      5.537      0.25     -56    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        75
#  comp.  1:       -51        38
#  comp.  2:       -59        39
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.962      0.19     -51    38
# Comp:  1                 Hbeta      3.725      0.19     -51    38
# Comp:  1                Halpha      12.94      0.19     -51    38
# Comp:  2             [SII]6716      3.404      0.19     -59    39
# Comp:  2             [SII]6731      2.371      0.19     -59    39
# Comp:  2              HeII4687    0.09656      0.19     -59    39
# Comp:  2               HeI5876     0.1398      0.19     -59    39
# Comp:  2          [OIII]5007_d      3.171      0.24     -59    39
# Comp:  2            [OI]6300_d     0.6407      0.24     -59    39
# Comp:  2           [NII]6583_d      5.423      0.24     -59    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        46
#  comp.  1:       -51        33
#  comp.  2:       -58        39
# chi2/DOF: 0.5834; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.691      0.19     -51    33
# Comp:  1                 Hbeta      3.138      0.19     -51    33
# Comp:  1                Halpha      12.58      0.19     -51    33
# Comp:  2             [SII]6716      3.559      0.19     -58    39
# Comp:  2             [SII]6731      2.366      0.19     -58    39
# Comp:  2              HeII4687    0.08107      0.19     -58    39
# Comp:  2               HeI5876    0.09009      0.19     -58    39
# Comp:  2          [OIII]5007_d      3.397      0.24     -58    39
# Comp:  2            [OI]6300_d     0.6018      0.24     -58    39
# Comp:  2           [NII]6583_d      5.373      0.24     -58    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        39
#  comp.  1:       -49        32
#  comp.  2:       -59        43
# chi2/DOF: 0.5883; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.695      0.19     -49    32
# Comp:  1                 Hbeta      3.278      0.19     -49    32
# Comp:  1                Halpha      12.47      0.19     -49    32
# Comp:  2             [SII]6716      3.718      0.20     -59    43
# Comp:  2             [SII]6731      2.471      0.20     -59    43
# Comp:  2              HeII4687    0.09289      0.20     -59    43
# Comp:  2               HeI5876    0.06370      0.20     -59    43
# Comp:  2          [OIII]5007_d      3.433      0.25     -59    43
# Comp:  2            [OI]6300_d     0.7485      0.25     -59    43
# Comp:  2           [NII]6583_d      5.494      0.25     -59    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        69
#  comp.  1:       -53        32
#  comp.  2:       -58        47
# chi2/DOF: 0.5875; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.652      0.19     -53    32
# Comp:  1                 Hbeta      3.208      0.19     -53    32
# Comp:  1                Halpha      12.55      0.19     -53    32
# Comp:  2             [SII]6716      3.607      0.20     -58    47
# Comp:  2             [SII]6731      2.357      0.20     -58    47
# Comp:  2              HeII4687      0.000      0.20     -58    47
# Comp:  2               HeI5876     0.1151      0.20     -58    47
# Comp:  2          [OIII]5007_d      3.288      0.25     -58    47
# Comp:  2            [OI]6300_d     0.6114      0.25     -58    47
# Comp:  2           [NII]6583_d      5.578      0.25     -58    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        79
#  comp.  1:       -54        35
#  comp.  2:       -57        46
# chi2/DOF: 0.5870; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.690      0.19     -54    35
# Comp:  1                 Hbeta      3.226      0.19     -54    35
# Comp:  1                Halpha      12.75      0.19     -54    35
# Comp:  2             [SII]6716      3.567      0.20     -57    46
# Comp:  2             [SII]6731      2.586      0.20     -57    46
# Comp:  2              HeII4687    0.02409      0.20     -57    46
# Comp:  2               HeI5876     0.1223      0.20     -57    46
# Comp:  2          [OIII]5007_d      3.487      0.25     -57    46
# Comp:  2            [OI]6300_d     0.8088      0.25     -57    46
# Comp:  2           [NII]6583_d      5.643      0.25     -57    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        51
#  comp.  1:       -51        34
#  comp.  2:       -58        38
# chi2/DOF: 0.5879; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.422      0.19     -51    34
# Comp:  1                 Hbeta      3.377      0.19     -51    34
# Comp:  1                Halpha      12.45      0.19     -51    34
# Comp:  2             [SII]6716      3.610      0.19     -58    38
# Comp:  2             [SII]6731      2.404      0.19     -58    38
# Comp:  2              HeII4687      0.000      0.19     -58    38
# Comp:  2               HeI5876    0.07484      0.19     -58    38
# Comp:  2          [OIII]5007_d      3.229      0.24     -58    38
# Comp:  2            [OI]6300_d     0.8122      0.24     -58    38
# Comp:  2           [NII]6583_d      5.295      0.24     -58    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        45
#  comp.  1:       -53        34
#  comp.  2:       -57        44
# chi2/DOF: 0.5888; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.601      0.19     -53    34
# Comp:  1                 Hbeta      3.265      0.19     -53    34
# Comp:  1                Halpha      12.62      0.19     -53    34
# Comp:  2             [SII]6716      3.740      0.20     -57    44
# Comp:  2             [SII]6731      2.504      0.20     -57    44
# Comp:  2              HeII4687    0.09712      0.20     -57    44
# Comp:  2               HeI5876     0.1653      0.20     -57    44
# Comp:  2          [OIII]5007_d      3.571      0.25     -57    44
# Comp:  2            [OI]6300_d     0.7279      0.25     -57    44
# Comp:  2           [NII]6583_d      5.430      0.25     -57    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        82
#  comp.  1:       -51        34
#  comp.  2:       -56        37
# chi2/DOF: 0.5870; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.578      0.19     -51    34
# Comp:  1                 Hbeta      3.402      0.19     -51    34
# Comp:  1                Halpha      12.49      0.19     -51    34
# Comp:  2             [SII]6716      3.462      0.19     -56    37
# Comp:  2             [SII]6731      2.346      0.19     -56    37
# Comp:  2              HeII4687      0.000      0.19     -56    37
# Comp:  2               HeI5876     0.1373      0.19     -56    37
# Comp:  2          [OIII]5007_d      3.190      0.24     -56    37
# Comp:  2            [OI]6300_d     0.6875      0.24     -56    37
# Comp:  2           [NII]6583_d      5.478      0.24     -56    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        67
#  comp.  1:       -51        34
#  comp.  2:       -59        42
# chi2/DOF: 0.5882; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.820      0.19     -51    34
# Comp:  1                 Hbeta      3.423      0.19     -51    34
# Comp:  1                Halpha      12.60      0.19     -51    34
# Comp:  2             [SII]6716      3.717      0.19     -59    42
# Comp:  2             [SII]6731      2.421      0.19     -59    42
# Comp:  2              HeII4687      0.000      0.19     -59    42
# Comp:  2               HeI5876    0.04230      0.19     -59    42
# Comp:  2          [OIII]5007_d      3.202      0.25     -59    42
# Comp:  2            [OI]6300_d     0.7124      0.25     -59    42
# Comp:  2           [NII]6583_d      5.310      0.25     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        60
#  comp.  1:       -53        32
#  comp.  2:       -57        40
# chi2/DOF: 0.5853; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.699      0.19     -53    32
# Comp:  1                 Hbeta      3.491      0.19     -53    32
# Comp:  1                Halpha      12.48      0.19     -53    32
# Comp:  2             [SII]6716      3.469      0.19     -57    40
# Comp:  2             [SII]6731      2.466      0.19     -57    40
# Comp:  2              HeII4687      0.000      0.19     -57    40
# Comp:  2               HeI5876     0.1303      0.19     -57    40
# Comp:  2          [OIII]5007_d      3.300      0.24     -57    40
# Comp:  2            [OI]6300_d     0.8194      0.24     -57    40
# Comp:  2           [NII]6583_d      5.410      0.24     -57    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        61
#  comp.  1:       -51        37
#  comp.  2:       -60        48
# chi2/DOF: 0.5868; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.821      0.19     -51    37
# Comp:  1                 Hbeta      3.583      0.19     -51    37
# Comp:  1                Halpha      12.83      0.19     -51    37
# Comp:  2             [SII]6716      3.601      0.20     -60    48
# Comp:  2             [SII]6731      2.616      0.20     -60    48
# Comp:  2              HeII4687     0.1004      0.20     -60    48
# Comp:  2               HeI5876     0.1144      0.20     -60    48
# Comp:  2          [OIII]5007_d      3.341      0.25     -60    48
# Comp:  2            [OI]6300_d     0.7444      0.25     -60    48
# Comp:  2           [NII]6583_d      5.605      0.25     -60    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        57
#  comp.  1:       -50        37
#  comp.  2:       -56        40
# chi2/DOF: 0.5868; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.776      0.19     -50    37
# Comp:  1                 Hbeta      3.470      0.19     -50    37
# Comp:  1                Halpha      12.70      0.19     -50    37
# Comp:  2             [SII]6716      3.671      0.19     -56    40
# Comp:  2             [SII]6731      2.349      0.19     -56    40
# Comp:  2              HeII4687      0.000      0.19     -56    40
# Comp:  2               HeI5876     0.1014      0.19     -56    40
# Comp:  2          [OIII]5007_d      3.134      0.24     -56    40
# Comp:  2            [OI]6300_d     0.8521      0.24     -56    40
# Comp:  2           [NII]6583_d      5.374      0.24     -56    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        33
#  comp.  1:       -51        31
#  comp.  2:       -58        35
# chi2/DOF: 0.5842; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.661      0.19     -51    31
# Comp:  1                 Hbeta      3.267      0.19     -51    31
# Comp:  1                Halpha      12.29      0.19     -51    31
# Comp:  2             [SII]6716      3.467      0.19     -58    35
# Comp:  2             [SII]6731      2.490      0.19     -58    35
# Comp:  2              HeII4687      0.000      0.19     -58    35
# Comp:  2               HeI5876     0.1096      0.19     -58    35
# Comp:  2          [OIII]5007_d      3.153      0.24     -58    35
# Comp:  2            [OI]6300_d     0.7749      0.24     -58    35
# Comp:  2           [NII]6583_d      5.275      0.24     -58    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        39
#  comp.  1:       -49        31
#  comp.  2:       -58        41
# chi2/DOF: 0.5830; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.683      0.19     -49    31
# Comp:  1                 Hbeta      3.406      0.19     -49    31
# Comp:  1                Halpha      12.38      0.19     -49    31
# Comp:  2             [SII]6716      3.572      0.19     -58    41
# Comp:  2             [SII]6731      2.478      0.19     -58    41
# Comp:  2              HeII4687      0.000      0.19     -58    41
# Comp:  2               HeI5876     0.1174      0.19     -58    41
# Comp:  2          [OIII]5007_d      3.141      0.25     -58    41
# Comp:  2            [OI]6300_d     0.7678      0.25     -58    41
# Comp:  2           [NII]6583_d      5.469      0.25     -58    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        83
#  comp.  1:       -51        38
#  comp.  2:       -58        42
# chi2/DOF: 0.5845; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.519      0.19     -51    38
# Comp:  1                 Hbeta      3.433      0.19     -51    38
# Comp:  1                Halpha      12.68      0.19     -51    38
# Comp:  2             [SII]6716      3.507      0.20     -58    42
# Comp:  2             [SII]6731      2.578      0.20     -58    42
# Comp:  2              HeII4687     0.1213      0.20     -58    42
# Comp:  2               HeI5876    0.07296      0.20     -58    42
# Comp:  2          [OIII]5007_d      3.111      0.25     -58    42
# Comp:  2            [OI]6300_d     0.7936      0.25     -58    42
# Comp:  2           [NII]6583_d      5.512      0.25     -58    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        53
#  comp.  1:       -50        32
#  comp.  2:       -60        43
# chi2/DOF: 0.5848; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.784      0.19     -50    32
# Comp:  1                 Hbeta      3.054      0.19     -50    32
# Comp:  1                Halpha      12.45      0.19     -50    32
# Comp:  2             [SII]6716      3.428      0.20     -60    43
# Comp:  2             [SII]6731      2.442      0.20     -60    43
# Comp:  2              HeII4687    0.02178      0.20     -60    43
# Comp:  2               HeI5876    0.05633      0.20     -60    43
# Comp:  2          [OIII]5007_d      3.504      0.25     -60    43
# Comp:  2            [OI]6300_d     0.6272      0.25     -60    43
# Comp:  2           [NII]6583_d      5.462      0.25     -60    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        92
#  comp.  1:       -54        35
#  comp.  2:       -59        38
# chi2/DOF: 0.5876; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.535      0.19     -54    35
# Comp:  1                 Hbeta      3.159      0.19     -54    35
# Comp:  1                Halpha      12.72      0.19     -54    35
# Comp:  2             [SII]6716      3.426      0.19     -59    38
# Comp:  2             [SII]6731      2.503      0.19     -59    38
# Comp:  2              HeII4687  0.0003139      0.19     -59    38
# Comp:  2               HeI5876     0.1062      0.19     -59    38
# Comp:  2          [OIII]5007_d      3.287      0.24     -59    38
# Comp:  2            [OI]6300_d     0.6352      0.24     -59    38
# Comp:  2           [NII]6583_d      5.280      0.24     -59    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        67
#  comp.  1:       -53        36
#  comp.  2:       -57        43
# chi2/DOF: 0.5854; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.803      0.19     -53    36
# Comp:  1                 Hbeta      3.335      0.19     -53    36
# Comp:  1                Halpha      12.80      0.19     -53    36
# Comp:  2             [SII]6716      3.450      0.20     -57    43
# Comp:  2             [SII]6731      2.508      0.20     -57    43
# Comp:  2              HeII4687    0.01634      0.20     -57    43
# Comp:  2               HeI5876     0.1583      0.20     -57    43
# Comp:  2          [OIII]5007_d      3.115      0.25     -57    43
# Comp:  2            [OI]6300_d     0.6965      0.25     -57    43
# Comp:  2           [NII]6583_d      5.562      0.25     -57    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        51
#  comp.  1:       -51        29
#  comp.  2:       -60        39
# chi2/DOF: 0.5840; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.671      0.19     -51    29
# Comp:  1                 Hbeta      3.128      0.19     -51    29
# Comp:  1                Halpha      12.35      0.19     -51    29
# Comp:  2             [SII]6716      3.527      0.19     -60    39
# Comp:  2             [SII]6731      2.388      0.19     -60    39
# Comp:  2              HeII4687     0.1004      0.19     -60    39
# Comp:  2               HeI5876     0.1482      0.19     -60    39
# Comp:  2          [OIII]5007_d      3.243      0.24     -60    39
# Comp:  2            [OI]6300_d     0.8793      0.24     -60    39
# Comp:  2           [NII]6583_d      5.455      0.24     -60    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        49
#  comp.  1:       -51        39
#  comp.  2:       -59        39
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.830      0.19     -51    39
# Comp:  1                 Hbeta      3.504      0.19     -51    39
# Comp:  1                Halpha      12.76      0.19     -51    39
# Comp:  2             [SII]6716      3.577      0.19     -59    39
# Comp:  2             [SII]6731      2.368      0.19     -59    39
# Comp:  2              HeII4687   0.009481      0.19     -59    39
# Comp:  2               HeI5876    0.08274      0.19     -59    39
# Comp:  2          [OIII]5007_d      3.438      0.24     -59    39
# Comp:  2            [OI]6300_d     0.7979      0.24     -59    39
# Comp:  2           [NII]6583_d      5.245      0.24     -59    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        50
#  comp.  1:       -50        33
#  comp.  2:       -59        41
# chi2/DOF: 0.5874; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.711      0.19     -50    33
# Comp:  1                 Hbeta      3.249      0.19     -50    33
# Comp:  1                Halpha      12.34      0.19     -50    33
# Comp:  2             [SII]6716      3.400      0.19     -59    41
# Comp:  2             [SII]6731      2.349      0.19     -59    41
# Comp:  2              HeII4687      0.000      0.19     -59    41
# Comp:  2               HeI5876    0.04811      0.19     -59    41
# Comp:  2          [OIII]5007_d      3.272      0.25     -59    41
# Comp:  2            [OI]6300_d     0.8074      0.25     -59    41
# Comp:  2           [NII]6583_d      5.533      0.25     -59    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        59
#  comp.  1:       -51        36
#  comp.  2:       -59        43
# chi2/DOF: 0.5876; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.955      0.19     -51    36
# Comp:  1                 Hbeta      3.450      0.19     -51    36
# Comp:  1                Halpha      12.88      0.19     -51    36
# Comp:  2             [SII]6716      3.535      0.20     -59    43
# Comp:  2             [SII]6731      2.403      0.20     -59    43
# Comp:  2              HeII4687    0.07597      0.20     -59    43
# Comp:  2               HeI5876     0.1347      0.20     -59    43
# Comp:  2          [OIII]5007_d      3.312      0.25     -59    43
# Comp:  2            [OI]6300_d     0.7725      0.25     -59    43
# Comp:  2           [NII]6583_d      5.484      0.25     -59    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        83
#  comp.  1:       -50        32
#  comp.  2:       -58        40
# chi2/DOF: 0.5849; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.425      0.19     -50    32
# Comp:  1                 Hbeta      3.403      0.19     -50    32
# Comp:  1                Halpha      12.23      0.19     -50    32
# Comp:  2             [SII]6716      3.439      0.19     -58    40
# Comp:  2             [SII]6731      2.411      0.19     -58    40
# Comp:  2              HeII4687    0.05707      0.19     -58    40
# Comp:  2               HeI5876     0.1712      0.19     -58    40
# Comp:  2          [OIII]5007_d      3.434      0.24     -58    40
# Comp:  2            [OI]6300_d     0.5438      0.24     -58    40
# Comp:  2           [NII]6583_d      5.330      0.24     -58    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        56
#  comp.  1:       -50        32
#  comp.  2:       -61        41
# chi2/DOF: 0.5880; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.746      0.19     -50    32
# Comp:  1                 Hbeta      3.455      0.19     -50    32
# Comp:  1                Halpha      12.37      0.19     -50    32
# Comp:  2             [SII]6716      3.601      0.19     -61    41
# Comp:  2             [SII]6731      2.461      0.19     -61    41
# Comp:  2              HeII4687     0.1639      0.19     -61    41
# Comp:  2               HeI5876     0.1082      0.19     -61    41
# Comp:  2          [OIII]5007_d      3.445      0.25     -61    41
# Comp:  2            [OI]6300_d     0.7303      0.25     -61    41
# Comp:  2           [NII]6583_d      5.376      0.25     -61    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        72
#  comp.  1:       -51        33
#  comp.  2:       -57        44
# chi2/DOF: 0.5847; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.610      0.19     -51    33
# Comp:  1                 Hbeta      3.331      0.19     -51    33
# Comp:  1                Halpha      12.43      0.19     -51    33
# Comp:  2             [SII]6716      3.501      0.20     -57    44
# Comp:  2             [SII]6731      2.401      0.20     -57    44
# Comp:  2              HeII4687      0.000      0.20     -57    44
# Comp:  2               HeI5876     0.1660      0.20     -57    44
# Comp:  2          [OIII]5007_d      3.526      0.25     -57    44
# Comp:  2            [OI]6300_d     0.5933      0.25     -57    44
# Comp:  2           [NII]6583_d      5.407      0.25     -57    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        59
#  comp.  1:       -51        29
#  comp.  2:       -59        42
# chi2/DOF: 0.5883; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.778      0.19     -51    29
# Comp:  1                 Hbeta      3.373      0.19     -51    29
# Comp:  1                Halpha      12.35      0.19     -51    29
# Comp:  2             [SII]6716      3.668      0.20     -59    42
# Comp:  2             [SII]6731      2.371      0.20     -59    42
# Comp:  2              HeII4687      0.000      0.20     -59    42
# Comp:  2               HeI5876     0.1043      0.20     -59    42
# Comp:  2          [OIII]5007_d      3.322      0.25     -59    42
# Comp:  2            [OI]6300_d     0.5699      0.25     -59    42
# Comp:  2           [NII]6583_d      5.365      0.25     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        45
#  comp.  1:       -50        34
#  comp.  2:       -59        45
# chi2/DOF: 0.5867; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.680      0.19     -50    34
# Comp:  1                 Hbeta      3.317      0.19     -50    34
# Comp:  1                Halpha      12.61      0.19     -50    34
# Comp:  2             [SII]6716      3.548      0.20     -59    45
# Comp:  2             [SII]6731      2.345      0.20     -59    45
# Comp:  2              HeII4687      0.000      0.20     -59    45
# Comp:  2               HeI5876    0.08177      0.20     -59    45
# Comp:  2          [OIII]5007_d      3.294      0.25     -59    45
# Comp:  2            [OI]6300_d     0.7343      0.25     -59    45
# Comp:  2           [NII]6583_d      5.465      0.25     -59    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        64
#  comp.  1:       -51        31
#  comp.  2:       -59        42
# chi2/DOF: 0.5882; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.632      0.19     -51    31
# Comp:  1                 Hbeta      3.267      0.19     -51    31
# Comp:  1                Halpha      12.27      0.19     -51    31
# Comp:  2             [SII]6716      3.571      0.19     -59    42
# Comp:  2             [SII]6731      2.466      0.19     -59    42
# Comp:  2              HeII4687    0.05654      0.19     -59    42
# Comp:  2               HeI5876     0.1589      0.19     -59    42
# Comp:  2          [OIII]5007_d      3.324      0.25     -59    42
# Comp:  2            [OI]6300_d     0.6499      0.25     -59    42
# Comp:  2           [NII]6583_d      5.473      0.25     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        47
#  comp.  1:       -50        32
#  comp.  2:       -60        42
# chi2/DOF: 0.5877; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.699      0.19     -50    32
# Comp:  1                 Hbeta      2.989      0.19     -50    32
# Comp:  1                Halpha      12.47      0.19     -50    32
# Comp:  2             [SII]6716      3.589      0.19     -60    42
# Comp:  2             [SII]6731      2.386      0.19     -60    42
# Comp:  2              HeII4687    0.01370      0.19     -60    42
# Comp:  2               HeI5876     0.1639      0.19     -60    42
# Comp:  2          [OIII]5007_d      3.239      0.25     -60    42
# Comp:  2            [OI]6300_d     0.6764      0.25     -60    42
# Comp:  2           [NII]6583_d      5.475      0.25     -60    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        59
#  comp.  1:       -51        39
#  comp.  2:       -60        39
# chi2/DOF: 0.5851; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.701      0.19     -51    39
# Comp:  1                 Hbeta      3.614      0.19     -51    39
# Comp:  1                Halpha      12.88      0.19     -51    39
# Comp:  2             [SII]6716      3.553      0.19     -60    39
# Comp:  2             [SII]6731      2.371      0.19     -60    39
# Comp:  2              HeII4687     0.1025      0.19     -60    39
# Comp:  2               HeI5876     0.1120      0.19     -60    39
# Comp:  2          [OIII]5007_d      3.362      0.24     -60    39
# Comp:  2            [OI]6300_d     0.7648      0.24     -60    39
# Comp:  2           [NII]6583_d      5.433      0.24     -60    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        59
#  comp.  1:       -53        30
#  comp.  2:       -60        45
# chi2/DOF: 0.5847; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.798      0.19     -53    30
# Comp:  1                 Hbeta      3.177      0.19     -53    30
# Comp:  1                Halpha      12.49      0.19     -53    30
# Comp:  2             [SII]6716      3.639      0.20     -60    45
# Comp:  2             [SII]6731      2.565      0.20     -60    45
# Comp:  2              HeII4687      0.000      0.20     -60    45
# Comp:  2               HeI5876    0.08292      0.20     -60    45
# Comp:  2          [OIII]5007_d      3.385      0.25     -60    45
# Comp:  2            [OI]6300_d     0.6311      0.25     -60    45
# Comp:  2           [NII]6583_d      5.553      0.25     -60    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        60
#  comp.  1:       -51        30
#  comp.  2:       -59        39
# chi2/DOF: 0.5873; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.722      0.19     -51    30
# Comp:  1                 Hbeta      3.330      0.19     -51    30
# Comp:  1                Halpha      12.42      0.19     -51    30
# Comp:  2             [SII]6716      3.568      0.19     -59    39
# Comp:  2             [SII]6731      2.559      0.19     -59    39
# Comp:  2              HeII4687      0.000      0.19     -59    39
# Comp:  2               HeI5876     0.1439      0.19     -59    39
# Comp:  2          [OIII]5007_d      3.415      0.24     -59    39
# Comp:  2            [OI]6300_d     0.8199      0.24     -59    39
# Comp:  2           [NII]6583_d      5.440      0.24     -59    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        60
#  comp.  1:       -51        32
#  comp.  2:       -57        40
# chi2/DOF: 0.5893; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        77
#  comp.  1:       -51        32
#  comp.  2:       -58        33
# chi2/DOF: 0.5857; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.727      0.19     -51    32
# Comp:  1                 Hbeta      3.203      0.19     -51    32
# Comp:  1                Halpha      12.31      0.19     -51    32
# Comp:  2             [SII]6716      3.370      0.19     -58    33
# Comp:  2             [SII]6731      2.278      0.19     -58    33
# Comp:  2              HeII4687    0.02861      0.19     -58    33
# Comp:  2               HeI5876     0.1762      0.19     -58    33
# Comp:  2          [OIII]5007_d      3.209      0.24     -58    33
# Comp:  2            [OI]6300_d     0.6693      0.24     -58    33
# Comp:  2           [NII]6583_d      5.155      0.24     -58    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        42
#  comp.  1:       -52        31
#  comp.  2:       -55        47
# chi2/DOF: 0.5861; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.738      0.19     -52    31
# Comp:  1                 Hbeta      3.490      0.19     -52    31
# Comp:  1                Halpha      12.43      0.19     -52    31
# Comp:  2             [SII]6716      3.488      0.20     -55    47
# Comp:  2             [SII]6731      2.596      0.20     -55    47
# Comp:  2              HeII4687      0.000      0.20     -55    47
# Comp:  2               HeI5876    0.06026      0.20     -55    47
# Comp:  2          [OIII]5007_d      3.258      0.25     -55    47
# Comp:  2            [OI]6300_d     0.7061      0.25     -55    47
# Comp:  2           [NII]6583_d      5.492      0.25     -55    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        64
#  comp.  1:       -51        28
#  comp.  2:       -55        39
# chi2/DOF: 0.5870; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.571      0.19     -51    28
# Comp:  1                 Hbeta      3.175      0.19     -51    28
# Comp:  1                Halpha      12.33      0.19     -51    28
# Comp:  2             [SII]6716      3.576      0.19     -55    39
# Comp:  2             [SII]6731      2.581      0.19     -55    39
# Comp:  2              HeII4687      0.000      0.19     -55    39
# Comp:  2               HeI5876     0.1007      0.19     -55    39
# Comp:  2          [OIII]5007_d      3.382      0.24     -55    39
# Comp:  2            [OI]6300_d     0.7359      0.24     -55    39
# Comp:  2           [NII]6583_d      5.355      0.24     -55    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        43
#  comp.  1:       -49        35
#  comp.  2:       -60        47
# chi2/DOF: 0.5830; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.726      0.19     -49    35
# Comp:  1                 Hbeta      3.671      0.19     -49    35
# Comp:  1                Halpha      12.67      0.19     -49    35
# Comp:  2             [SII]6716      3.694      0.20     -60    47
# Comp:  2             [SII]6731      2.452      0.20     -60    47
# Comp:  2              HeII4687      0.000      0.20     -60    47
# Comp:  2               HeI5876     0.1404      0.20     -60    47
# Comp:  2          [OIII]5007_d      3.482      0.25     -60    47
# Comp:  2            [OI]6300_d     0.6276      0.25     -60    47
# Comp:  2           [NII]6583_d      5.647      0.25     -60    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        46
#  comp.  1:       -53        34
#  comp.  2:       -56        43
# chi2/DOF: 0.5828; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.570      0.19     -53    34
# Comp:  1                 Hbeta      3.430      0.19     -53    34
# Comp:  1                Halpha      12.64      0.19     -53    34
# Comp:  2             [SII]6716      3.626      0.20     -56    43
# Comp:  2             [SII]6731      2.495      0.20     -56    43
# Comp:  2              HeII4687     0.1149      0.20     -56    43
# Comp:  2               HeI5876     0.1531      0.20     -56    43
# Comp:  2          [OIII]5007_d      3.388      0.25     -56    43
# Comp:  2            [OI]6300_d     0.6337      0.25     -56    43
# Comp:  2           [NII]6583_d      5.557      0.25     -56    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        80
#  comp.  1:       -52        28
#  comp.  2:       -58        41
# chi2/DOF: 0.5871; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.679      0.19     -52    28
# Comp:  1                 Hbeta      3.094      0.19     -52    28
# Comp:  1                Halpha      12.29      0.19     -52    28
# Comp:  2             [SII]6716      3.716      0.19     -58    41
# Comp:  2             [SII]6731      2.574      0.19     -58    41
# Comp:  2              HeII4687      0.000      0.19     -58    41
# Comp:  2               HeI5876     0.1148      0.19     -58    41
# Comp:  2          [OIII]5007_d      3.180      0.25     -58    41
# Comp:  2            [OI]6300_d     0.6817      0.25     -58    41
# Comp:  2           [NII]6583_d      5.460      0.25     -58    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        64
#  comp.  1:       -53        34
#  comp.  2:       -59        44
# chi2/DOF: 0.5855; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.465      0.19     -53    34
# Comp:  1                 Hbeta      3.382      0.19     -53    34
# Comp:  1                Halpha      12.54      0.19     -53    34
# Comp:  2             [SII]6716      3.505      0.20     -59    44
# Comp:  2             [SII]6731      2.387      0.20     -59    44
# Comp:  2              HeII4687      0.000      0.20     -59    44
# Comp:  2               HeI5876     0.1028      0.20     -59    44
# Comp:  2          [OIII]5007_d      3.221      0.25     -59    44
# Comp:  2            [OI]6300_d     0.6222      0.25     -59    44
# Comp:  2           [NII]6583_d      5.441      0.25     -59    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        70
#  comp.  1:       -53        37
#  comp.  2:       -58        46
# chi2/DOF: 0.5884; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.853      0.19     -53    37
# Comp:  1                 Hbeta      3.510      0.19     -53    37
# Comp:  1                Halpha      12.76      0.19     -53    37
# Comp:  2             [SII]6716      3.529      0.20     -58    46
# Comp:  2             [SII]6731      2.523      0.20     -58    46
# Comp:  2              HeII4687    0.02305      0.20     -58    46
# Comp:  2               HeI5876     0.1189      0.20     -58    46
# Comp:  2          [OIII]5007_d      3.284      0.25     -58    46
# Comp:  2            [OI]6300_d     0.7162      0.25     -58    46
# Comp:  2           [NII]6583_d      5.431      0.25     -58    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        50
#  comp.  1:       -50        28
#  comp.  2:       -58        42
# chi2/DOF: 0.5877; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.664      0.19     -50    28
# Comp:  1                 Hbeta      3.153      0.19     -50    28
# Comp:  1                Halpha      12.24      0.19     -50    28
# Comp:  2             [SII]6716      3.614      0.20     -58    42
# Comp:  2             [SII]6731      2.503      0.20     -58    42
# Comp:  2              HeII4687      0.000      0.20     -58    42
# Comp:  2               HeI5876    0.04237      0.20     -58    42
# Comp:  2          [OIII]5007_d      3.279      0.25     -58    42
# Comp:  2            [OI]6300_d     0.6851      0.25     -58    42
# Comp:  2           [NII]6583_d      5.499      0.25     -58    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        79
#  comp.  1:       -52        35
#  comp.  2:       -60        44
# chi2/DOF: 0.5864; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.731      0.19     -52    35
# Comp:  1                 Hbeta      3.356      0.19     -52    35
# Comp:  1                Halpha      12.56      0.19     -52    35
# Comp:  2             [SII]6716      3.503      0.20     -60    44
# Comp:  2             [SII]6731      2.567      0.20     -60    44
# Comp:  2              HeII4687    0.01924      0.20     -60    44
# Comp:  2               HeI5876    0.09841      0.20     -60    44
# Comp:  2          [OIII]5007_d      3.373      0.25     -60    44
# Comp:  2            [OI]6300_d     0.7540      0.25     -60    44
# Comp:  2           [NII]6583_d      5.538      0.25     -60    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        15
#  comp.  1:       -52        30
#  comp.  2:       -57        42
# chi2/DOF: 0.5862; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.634      0.19     -52    30
# Comp:  1                 Hbeta      3.335      0.19     -52    30
# Comp:  1                Halpha      12.51      0.19     -52    30
# Comp:  2             [SII]6716      3.655      0.19     -57    42
# Comp:  2             [SII]6731      2.430      0.19     -57    42
# Comp:  2              HeII4687      0.000      0.19     -57    42
# Comp:  2               HeI5876    0.08975      0.19     -57    42
# Comp:  2          [OIII]5007_d      3.475      0.25     -57    42
# Comp:  2            [OI]6300_d     0.6096      0.25     -57    42
# Comp:  2           [NII]6583_d      5.521      0.25     -57    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        56
#  comp.  1:       -52        35
#  comp.  2:       -58        39
# chi2/DOF: 0.5869; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.821      0.19     -52    35
# Comp:  1                 Hbeta      3.611      0.19     -52    35
# Comp:  1                Halpha      12.59      0.19     -52    35
# Comp:  2             [SII]6716      3.615      0.19     -58    39
# Comp:  2             [SII]6731      2.491      0.19     -58    39
# Comp:  2              HeII4687      0.000      0.19     -58    39
# Comp:  2               HeI5876     0.1057      0.19     -58    39
# Comp:  2          [OIII]5007_d      3.475      0.24     -58    39
# Comp:  2            [OI]6300_d     0.8323      0.24     -58    39
# Comp:  2           [NII]6583_d      5.476      0.24     -58    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        90
#  comp.  1:       -52        31
#  comp.  2:       -55        36
# chi2/DOF: 0.5871; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.638      0.19     -52    31
# Comp:  1                 Hbeta      3.157      0.19     -52    31
# Comp:  1                Halpha      12.30      0.19     -52    31
# Comp:  2             [SII]6716      3.464      0.19     -55    36
# Comp:  2             [SII]6731      2.444      0.19     -55    36
# Comp:  2              HeII4687      0.000      0.19     -55    36
# Comp:  2               HeI5876    0.09543      0.19     -55    36
# Comp:  2          [OIII]5007_d      3.172      0.24     -55    36
# Comp:  2            [OI]6300_d     0.8601      0.24     -55    36
# Comp:  2           [NII]6583_d      5.335      0.24     -55    36
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.10210402, 0.18003728, 0.2436174 , 0.13288572, 0.10915553,
#        0.04290124, 0.05288745, 0.13010997, 0.11228075, 0.14647123])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 1.44415082,  3.30325381, 16.99827494,  4.98881482,  3.45012357,
#         0.        ,  0.1245693 ,  3.4377161 ,  0.94555166,  7.4414088 ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_11_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_11", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_11_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_11_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_11_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.206483    0.014599
# 1         Hbeta  0.472295    0.025742
# 2        Halpha  2.430392    0.034832
# 3     [SII]6716  0.713294    0.019000
# 4     [SII]6731  0.493294    0.015607
# 5      HeII4687  0.000000    0.006134
# 6       HeI5876  0.017811    0.007562
# 7  [OIII]5007_d  0.491520    0.018603
# 8    [OI]6300_d  0.135194    0.016054
# 9   [NII]6583_d  1.063963    0.020942
#           Name      Flux  Error_flux
# 0       Hgamma  0.206483    0.014599
# 1        Hbeta  0.472295    0.025742
# 2       Halpha  2.430392    0.034832
# 3    [SII]6716  0.713294    0.019000
# 4    [SII]6731  0.493294    0.015607
# 5     HeII4687  0.000000    0.006134
# 6      HeI5876  0.017811    0.007562
# 7   [OIII]4959  0.122880    0.018603
# 8   [OIII]5007  0.368640    0.018603
# 9     [OI]6300  0.101395    0.016054
# 10    [OI]6364  0.033798    0.016054
# 11   [NII]6548  0.265991    0.020942
# 12   [NII]6583  0.797972    0.020942

# %%
np.median(flux_rf_rebin)
# Out:
# 0.1429787447671556
