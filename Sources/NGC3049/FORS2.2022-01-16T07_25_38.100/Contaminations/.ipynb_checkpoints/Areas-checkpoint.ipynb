# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os
from scipy.integrate import simpson

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     387   (2094, 965)   float32
#   1  IMAGE.ERR     1 ImageHDU        68   (2094, 965)   float32

# %%
image_cut = image[67:167, 0:1890]
image_error_cut = image_error[67:167, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

z = 0.00485
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII_1 = 6548 * (1+z) 
l_NII_2 = 6583 * (1+z)
l_SII_1 = 6717 * (1+z)
l_SII_2 = 6731 * (1+z)
l_OIII_1 = 4959 * (1+z)
l_OIII_2 = 5007 * (1+z)

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, params):
    """ Profilo Sérsic 1D centrato in x_0 """
    I_e, r_e, n, x_0 = params
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
    
def sersic_1d_convolved(x, params):
    """ Sérsic convoluto con PSF gaussiana """
    profile = sersic_1d(x, params)
    psf = Gaussian1DKernel(stddev = sigma, mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    return conv_profile

def model_convolved(x, params1, params2, params3):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, params1) +
        sersic_1d(x_hr, params2) +
        sersic_1d(x_hr, params3) #+
       # sersic_1d(x_hr, params4)
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

# %%
seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/PSF/Real_seeing_NGC3049.txt")
sigma = seeing[-1] / 2.35
x_axes = np.arange(0, 100, 1)

# %%
def single_integral(x, params, a, b):
    func = sersic_1d_convolved(x, params)
    mask = (x >= a)*(x <= b)
    
    print(f"Punti nella maschera: {mask.sum()}")
    print(f"Valori func nella maschera: min={func[mask].min():.2e}, max={func[mask].max():.2e}")
    
    if mask.sum() < 2:
        print("ERRORE: Troppo pochi punti per l'integrazione!")
        return 0
        
    integral = simpson(y = func[mask], x = x[mask])
    return integral

def total_integral(x, params1, params2, params3, a, b):
    func = model_convolved(x, params1, params2, params3)
    mask = (x >= a)*(x <= b)
    integral = simpson(y = func[mask], x = x[mask])
    return integral  

def contamination(x, params1, params2, params3, a, b): 
    # Test le singole funzioni
    func1 = sersic_1d_convolved(x, params1)
    func2 = sersic_1d_convolved(x, params2) 
    func3 = sersic_1d_convolved(x, params3)
    
    print(f"func1 range: {func1.min():.2e} to {func1.max():.2e}")
    print(f"func2 range: {func2.min():.2e} to {func2.max():.2e}")
    print(f"func3 range: {func3.min():.2e} to {func3.max():.2e}")
    blue_area = single_integral(x, params1, a, b) 
    green_area = single_integral(x, params2, a, b)
    purple_area = single_integral(x, params3, a, b)
    sum_area = blue_area + green_area +purple_area 
    total_area = total_integral(x, params1, params2, params3, a, b)
    print(blue_area)
    print(green_area)
    print(purple_area)
    print(sum_area)
    print(total_area)
    return [(blue_area*100)/sum_area, (green_area*100)/sum_area, (purple_area*100)/sum_area]

# %% [markdown]
# ## Halpha

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))
fit_HA = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Halpha_fit.csv", index_col=0)

# %%
data1 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 1'].iloc[3] -1, 
                                                                fit_HA['Component 1'].iloc[3] + 1)
data2 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 2'].iloc[3] -1, 
                                                                fit_HA['Component 2'].iloc[3] + 1)
data3 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 3'].iloc[3] -1, 
                                                                fit_HA['Component 3'].iloc[3] + 1)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Halpha_1s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.80e+01, max=1.28e+02
# Punti nella maschera: 3
# Valori func nella maschera: min=1.14e-01, max=1.99e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.04e-02, max=1.40e-02
# 229.81558669815132
# 0.3038025978096549
# 0.02425143810358439
# 230.14364073406458
# 157.20758858067026
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=4.99e+00, max=6.66e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=6.29e+00, max=8.43e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.46e-02, max=7.43e-02
# 11.546665833270254
# 15.42648379253443
# 0.12789073947561005
# 27.101040365280294
# 24.898882816948856
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=3.05e-01, max=3.49e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.18e-03, max=1.77e-03
# Punti nella maschera: 3
# Valori func nella maschera: min=1.04e+01, max=1.15e+01
# 0.6532074977368665
# 0.002912253381803475
# 22.287187603711608
# 22.943307354830278
# 22.41530196951901
#            Peak 1     Peak 2     Peak 3
# Blue    99.857457  42.605987   2.847050
# Green    0.132006  56.922109   0.012693
# Purple   0.010538   0.471903  97.140256

# %%
data1 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 1'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 2*sigma)
data2 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 2'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 2*sigma)
data3 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 3'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 2*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Halpha_2s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.80e+01, max=1.28e+02
# Punti nella maschera: 3
# Valori func nella maschera: min=1.14e-01, max=1.99e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.04e-02, max=1.40e-02
# 229.81558669815132
# 0.3038025978096549
# 0.02425143810358439
# 230.14364073406458
# 157.20758858067026
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=4.99e+00, max=6.66e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=6.29e+00, max=8.43e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.46e-02, max=7.43e-02
# 11.546665833270254
# 15.42648379253443
# 0.12789073947561005
# 27.101040365280294
# 24.898882816948856
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=3.05e-01, max=3.49e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.18e-03, max=1.77e-03
# Punti nella maschera: 3
# Valori func nella maschera: min=1.04e+01, max=1.15e+01
# 0.6532074977368665
# 0.002912253381803475
# 22.287187603711608
# 22.943307354830278
# 22.41530196951901
#            Peak 1     Peak 2     Peak 3
# Blue    99.857457  42.605987   2.847050
# Green    0.132006  56.922109   0.012693
# Purple   0.010538   0.471903  97.140256

# %%
data1 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 1'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 3*sigma)
data2 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 2'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 3*sigma)
data3 = contamination(x_axes, fit_HA['Component 1'], fit_HA['Component 2'], fit_HA['Component 3'], fit_HA['Component 3'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 3*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Halpha_3s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=4.45e+01, max=1.28e+02
# Punti nella maschera: 5
# Valori func nella maschera: min=8.68e-02, max=2.67e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=8.98e-03, max=1.63e-02
# 349.9631723255743
# 0.634396988347853
# 0.04905027517138982
# 350.6466195890936
# 262.58286056924317
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=4.37e+00, max=7.79e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=3.56e+00, max=8.43e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=4.69e-02, max=8.67e-02
# 23.42578574760533
# 24.759408173718708
# 0.2588821324259754
# 48.44407605375002
# 45.83957490507943
# func1 range: 7.82e-02 to 1.28e+02
# func2 range: 3.29e-05 to 8.43e+00
# func3 range: 4.06e-05 to 1.15e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=2.86e-01, max=3.74e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=9.69e-04, max=2.17e-03
# Punti nella maschera: 5
# Valori func nella maschera: min=8.46e+00, max=1.15e+01
# 1.3099600875339992
# 0.005949792395215674
# 41.0082739619
# 42.32418384182922
# 41.71061491176953
#            Peak 1     Peak 2     Peak 3
# Blue    99.805089  48.356347   3.095063
# Green    0.180922  51.109259   0.014058
# Purple   0.013989   0.534394  96.890879

# %% [markdown]
# ## HBeta

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))
fit = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Fit/Hbeta_fit.csv", index_col = 0)

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -sigma, 
                                                                fit_HA['Component 1'].iloc[3] + sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -sigma, 
                                                                fit_HA['Component 2'].iloc[3] + sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -sigma, 
                                                                fit_HA['Component 3'].iloc[3] + sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Hbeta_1s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 1
# Valori func nella maschera: min=1.79e+00, max=1.79e+00
# ERRORE: Troppo pochi punti per l'integrazione!
# Punti nella maschera: 1
# Valori func nella maschera: min=1.14e+00, max=1.14e+00
# ERRORE: Troppo pochi punti per l'integrazione!
# Punti nella maschera: 1
# Valori func nella maschera: min=3.25e-02, max=3.25e-02
# ERRORE: Troppo pochi punti per l'integrazione!
# 0
# 0
# 0
# 0
# 0.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -sigma,
#       2                                                                 fit_HA['Component 1'].iloc[3] + sigma)
#       3 data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -sigma,
#       4                                                                 fit_HA['Component 2'].iloc[3] + sigma)
#       5 data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -sigma,
#       6                                                                 fit_HA['Component 3'].iloc[3] + sigma)
#
# Cell In[17], line 40, in contamination(x, params1, params2, params3, a, b)
#      38 print(sum_area)
#      39 print(total_area)
# ---> 40 return [(blue_area*100)/sum_area, (green_area*100)/sum_area, (purple_area*100)/sum_area]
#
# ZeroDivisionError: division by zero

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 2*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 2*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 2*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Hbeta_2s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.55e+00, max=2.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=9.35e-01, max=1.38e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.34e-02, max=4.53e-02
# 3.5988252695260243
# 2.2885492601563193
# 0.06628657058044038
# 5.953661100262784
# 5.939323769162478
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.68e+00, max=2.35e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=7.08e+00, max=9.63e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=8.32e-01, max=1.56e+00
# 3.9680680872106024
# 16.665267146536216
# 2.314140265666881
# 22.947475499413702
# 22.91084920312376
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.78e-01, max=1.95e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=3.98e-02, max=6.09e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=3.39e-02, max=6.55e-02
# 0.372308349299654
# 0.09917006005590036
# 0.09603708244713519
# 0.5675154918026896
# 0.5682761212174805
#            Peak 1     Peak 2     Peak 3
# Blue    60.447264  17.291959  65.603205
# Green   38.439361  72.623532  17.474423
# Purple   1.113375  10.084509  16.922372

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 3*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 3*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 3*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_Hbeta_3s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.36e+00, max=2.55e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=7.68e-01, max=1.67e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.67e-02, max=6.30e-02
# 7.357610650750673
# 4.6599480339371535
# 0.13981583074371332
# 12.15737451543154
# 12.127281186578532
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.46e+00, max=2.91e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=5.99e+00, max=1.05e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=6.06e-01, max=2.12e+00
# 8.15126660439487
# 33.3307697068345
# 4.85114246266053
# 46.3331787738899
# 46.27838054977914
# func1 range: 6.47e-02 to 7.37e+00
# func2 range: 2.65e-04 to 1.05e+01
# func3 range: 5.16e-08 to 1.99e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.70e-01, max=2.04e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=3.21e-02, max=7.52e-02
# Punti nella maschera: 5
# Valori func nella maschera: min=2.43e-02, max=9.10e-02
# 0.7457241969750159
# 0.2027502669310546
# 0.20247309847741465
# 1.150947562383485
# 1.1525135708398087
#            Peak 1     Peak 2     Peak 3
# Blue    60.519733  17.592720  64.792196
# Green   38.330217  71.937153  17.615943
# Purple   1.150050  10.470127  17.591861

# %% [markdown]
# ## NII

# %%
mask_NII = (wv > l_NII_2-8)*(wv < l_NII_2+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))
fit = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Fit/NII_fit.csv", index_col = 0)

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] - 1, 
                                                                fit_HA['Component 1'].iloc[3] +  1)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] - 1, 
                                                                fit_HA['Component 2'].iloc[3] +  1)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] - 1, 
                                                                fit_HA['Component 3'].iloc[3] +  1)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_NII_1s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.15e+00, max=1.67e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=6.67e-01, max=7.92e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=5.60e-04, max=1.93e-03
# 2.782713282582016
# 1.4537187042065087
# 0.002223356836389304
# 4.238655343624914
# 4.229704062312049
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.96e+00, max=3.09e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.56e+00, max=4.63e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.32e-01, max=5.55e-01
# 4.929486515699844
# 6.804877747896239
# 0.7460567597330892
# 12.480421023329171
# 12.466906113961457
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.99e-02, max=3.70e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=2.49e-01, max=2.77e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.65e-03, max=8.45e-03
# 0.0666620700298953
# 0.5246987051528433
# 0.010053949701444607
# 0.6014147248841832
# 0.6018785610893389
#            Peak 1     Peak 2     Peak 3
# Blue    65.650850  39.497758  11.084210
# Green   34.296695  54.524425  87.244074
# Purple   0.052454   5.977817   1.671717

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 2*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 2*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 2*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_NII_2s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.15e+00, max=1.67e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=6.67e-01, max=7.92e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=5.60e-04, max=1.93e-03
# 2.782713282582016
# 1.4537187042065087
# 0.002223356836389304
# 4.238655343624914
# 4.229704062312049
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.96e+00, max=3.09e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.56e+00, max=4.63e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.32e-01, max=5.55e-01
# 4.929486515699844
# 6.804877747896239
# 0.7460567597330892
# 12.480421023329171
# 12.466906113961457
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.99e-02, max=3.70e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=2.49e-01, max=2.77e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.65e-03, max=8.45e-03
# 0.0666620700298953
# 0.5246987051528433
# 0.010053949701444607
# 0.6014147248841832
# 0.6018785610893389
#            Peak 1     Peak 2     Peak 3
# Blue    65.650850  39.497758  11.084210
# Green   34.296695  54.524425  87.244074
# Purple   0.052454   5.977817   1.671717

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 3*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 3*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 3*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_NII_3s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=9.68e-01, max=2.05e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=6.15e-01, max=8.69e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=2.96e-04, max=3.49e-03
# 5.691382989328165
# 2.9243039733164062
# 0.0052746747044278034
# 8.620961637348998
# 8.602402002654543
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.61e+00, max=4.06e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=2.10e+00, max=5.85e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.46e-01, max=8.33e-01
# 10.244496782657908
# 14.43686962997905
# 1.617996920029618
# 26.299363332666577
# 26.408992942468718
# func1 range: 3.91e-03 to 6.66e+00
# func2 range: 7.28e-02 to 5.85e+00
# func3 range: 1.56e-17 to 8.85e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=2.69e-02, max=4.12e-02
# Punti nella maschera: 5
# Valori func nella maschera: min=2.36e-01, max=2.92e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.45e-03, max=1.48e-02
# 0.1341489605055398
# 1.0514884812827874
# 0.023377959704244826
# 1.2090154014925718
# 1.209962014586713
#            Peak 1     Peak 2     Peak 3
# Blue    66.017960  38.953402  11.095720
# Green   33.920856  54.894369  86.970644
# Purple   0.061184   6.152228   1.933636

# %% [markdown]
# ## SII

# %%
mask_SII = (wv > l_SII_1-8)*(wv < l_SII_1+8)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))
fit = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Fit/SII_fit.csv", index_col = 0)

# %%
fit
# Out:
#      Component 1  Component 2  Component 3
# I_e       0.5006       0.0956       2.2215
# r_e      13.3076      49.9997       5.8576
# n         1.5454       2.2675       0.5849
# x_0      44.7996      50.8886      60.0323

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -1, 
                                                                fit_HA['Component 1'].iloc[3] + 1)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -1, 
                                                                fit_HA['Component 2'].iloc[3] + 1)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -1, 
                                                                fit_HA['Component 3'].iloc[3] + 1)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_SII_1s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.14e+00, max=1.61e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.89e-01, max=6.91e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.11e-04, max=2.87e-03
# 2.706661398392062
# 1.2758720588630275
# 0.003282360047382928
# 3.9858158173024725
# 3.977928576634479
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.79e+00, max=2.72e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.99e+00, max=3.32e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.92e-01, max=6.31e-01
# 4.4233969697563
# 5.112207213275295
# 0.8877548886486705
# 10.423359071680265
# 10.39867177920965
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=4.05e-02, max=4.90e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=2.22e-01, max=2.46e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.99e-03, max=9.70e-03
# 0.08920341970275177
# 0.4677016136064445
# 0.01148468808965965
# 0.5683897213988559
# 0.5688278026396751
#            Peak 1     Peak 2     Peak 3
# Blue    67.907337  42.437346  15.694059
# Green   32.010311  49.045679  82.285375
# Purple   0.082351   8.516975   2.020566

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 2*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 2*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 2*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_SII_2s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.14e+00, max=1.61e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.89e-01, max=6.91e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.11e-04, max=2.87e-03
# 2.706661398392062
# 1.2758720588630275
# 0.003282360047382928
# 3.9858158173024725
# 3.977928576634479
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.79e+00, max=2.72e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=1.99e+00, max=3.32e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=2.92e-01, max=6.31e-01
# 4.4233969697563
# 5.112207213275295
# 0.8877548886486705
# 10.423359071680265
# 10.39867177920965
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=4.05e-02, max=4.90e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=2.22e-01, max=2.46e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.99e-03, max=9.70e-03
# 0.08920341970275177
# 0.4677016136064445
# 0.01148468808965965
# 0.5683897213988559
# 0.5688278026396751
#            Peak 1     Peak 2     Peak 3
# Blue    67.907337  42.437346  15.694059
# Green   32.010311  49.045679  82.285375
# Purple   0.082351   8.516975   2.020566

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 3*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 3*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 3*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_SII_3s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=9.69e-01, max=1.94e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=5.47e-01, max=7.52e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=4.18e-04, max=5.24e-03
# 5.521725175831564
# 2.56438967984433
# 0.007821457747824102
# 8.093936313423718
# 8.07760612082522
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.49e+00, max=3.50e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.67e+00, max=3.84e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=1.91e-01, max=8.94e-01
# 9.146112083646656
# 10.592380945760437
# 1.883122800594879
# 21.621615830001975
# 21.498733007097513
# func1 range: 6.35e-03 to 5.56e+00
# func2 range: 6.91e-02 to 3.84e+00
# func3 range: 1.08e-19 to 5.10e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=3.69e-02, max=5.40e-02
# Punti nella maschera: 5
# Valori func nella maschera: min=2.12e-01, max=2.59e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.61e-03, max=1.69e-02
# 0.17930709225289343
# 0.9370407112681796
# 0.026732451234711865
# 1.1430802547557848
# 1.1439769253818766
#            Peak 1     Peak 2     Peak 3
# Blue    68.220517  42.300780  15.686308
# Green   31.682850  48.989775  81.975059
# Purple   0.096634   8.709445   2.338633

# %% [markdown]
# ## OIII

# %%
mask_OIII = (wv > l_OIII_2-8)*(wv < l_OIII_2+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))
fit = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Fit/OIII_fit.csv", index_col = 0)

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -1, 
                                                                fit_HA['Component 1'].iloc[3] + 1)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -1, 
                                                                fit_HA['Component 2'].iloc[3] + 1)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -1, 
                                                                fit_HA['Component 3'].iloc[3] + 1)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_OIII_1s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.52e+00, max=3.78e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=9.56e-01, max=1.17e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.87e-03, max=1.53e-02
# 6.210193812584805
# 2.1161708663184915
# 0.019730514053681748
# 8.346095192956978
# 8.325588672785893
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=4.16e+00, max=6.35e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.23e+00, max=1.23e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.80e-01, max=2.01e+00
# 10.338270405496559
# 15.838720128782088
# 2.7426314114620234
# 28.91962194574067
# 29.309693377989227
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.20e-02, max=1.72e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=3.27e-01, max=3.67e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=7.65e-03, max=1.99e-02
# 0.02888330669038279
# 0.6932188453170168
# 0.02563906638060017
# 0.7477412183879998
# 0.7483848327233452
#            Peak 1     Peak 2     Peak 3
# Blue    74.408375  35.748290   3.862741
# Green   25.355221  54.768075  92.708390
# Purple   0.236404   9.483635   3.428869

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 2*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 2*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -2*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 2*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_OIII_2s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=2.52e+00, max=3.78e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=9.56e-01, max=1.17e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.87e-03, max=1.53e-02
# 6.210193812584805
# 2.1161708663184915
# 0.019730514053681748
# 8.346095192956978
# 8.325588672785893
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=4.16e+00, max=6.35e+00
# Punti nella maschera: 3
# Valori func nella maschera: min=5.23e+00, max=1.23e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=8.80e-01, max=2.01e+00
# 10.338270405496559
# 15.838720128782088
# 2.7426314114620234
# 28.91962194574067
# 29.309693377989227
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 3
# Valori func nella maschera: min=1.20e-02, max=1.72e-02
# Punti nella maschera: 3
# Valori func nella maschera: min=3.27e-01, max=3.67e-01
# Punti nella maschera: 3
# Valori func nella maschera: min=7.65e-03, max=1.99e-02
# 0.02888330669038279
# 0.6932188453170168
# 0.02563906638060017
# 0.7477412183879998
# 0.7483848327233452
#            Peak 1     Peak 2     Peak 3
# Blue    74.408375  35.748290   3.862741
# Green   25.355221  54.768075  92.708390
# Purple   0.236404   9.483635   3.428869

# %%
data1 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 1'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 1'].iloc[3] + 3*sigma)
data2 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 2'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 2'].iloc[3] + 3*sigma)
data3 = contamination(x_axes, fit['Component 1'], fit['Component 2'], fit['Component 3'], fit_HA['Component 3'].iloc[3] -3*sigma, 
                                                                fit_HA['Component 3'].iloc[3] + 3*sigma)

data = np.concatenate([np.array(data1).reshape(-1, 1),np.array(data2).reshape(-1, 1), 
                        np.array(data3).reshape(-1, 1)], axis=1)

df = pd.DataFrame(data, 
                  columns=[f'Peak {i+1}' for i in range(3)],
                  index=['Blue', 'Green', 'Purple'])
print(df)

df_path = os.path.join('Areas_OIII_3s.csv')
df.to_csv(df_path, float_format='%.3f')
# Out:
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=2.06e+00, max=4.66e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=8.71e-01, max=1.31e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=3.61e-03, max=2.46e-02
# 12.694291655983182
# 4.266522807099944
# 0.043974265891741
# 17.004788728974866
# 16.962734835923776
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=3.39e+00, max=7.89e+00
# Punti nella maschera: 5
# Valori func nella maschera: min=3.99e+00, max=1.85e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=5.76e-01, max=2.99e+00
# 21.185440889560976
# 35.84274490165976
# 5.93045970752404
# 62.95864549874477
# 66.49961027604118
# func1 range: 3.93e-04 to 1.11e+01
# func2 range: 9.06e-02 to 1.92e+01
# func3 range: 8.92e-12 to 3.78e+01
# Punti nella maschera: 5
# Valori func nella maschera: min=1.00e-02, max=2.06e-02
# Punti nella maschera: 5
# Valori func nella maschera: min=3.10e-01, max=3.90e-01
# Punti nella maschera: 5
# Valori func nella maschera: min=4.71e-03, max=3.18e-02
# 0.05871277548598447
# 1.3898109736309596
# 0.05707429489954524
# 1.5055980440164893
# 1.506916066237988
#            Peak 1     Peak 2     Peak 3
# Blue    74.651275  33.649772   3.899631
# Green   25.090125  56.930616  92.309563
# Purple   0.258599   9.419611   3.790806
