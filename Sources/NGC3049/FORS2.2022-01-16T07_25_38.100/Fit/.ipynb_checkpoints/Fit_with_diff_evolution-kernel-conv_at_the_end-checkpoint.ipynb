# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     387   (2094, 965)   float32
#   1  IMAGE.ERR     1 ImageHDU        68   (2094, 965)   float32

# %%
image_cut = image[67:167, 0:1890]
image_error_cut = image_error[67:167, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.00485
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/PSF/Real_seeing_NGC3049.txt")
sigmas = seeing / 2.35
n_component = 3
print(sigmas)
# Out:
# [0.8364224  0.98783034 0.83391649 0.83519425 0.97988724 0.84425532]

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[67:167, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     387   (2094, 965)   float32
#   1  IMAGE.ERR     1 ImageHDU        68   (2094, 965)   float32
# Text(0.5, 0, 'wavelength')

# %%
mask_sky = (y > 22)*(y < 32)
mask_wv = wv > 4450.5
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/Propag_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (38, 40),   # x_0: posizione da 0 a 100

    (0, 5),
    (0, 5),
    (0.1, 10),
    (47, 49),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (80, 81)
]


def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=1.7028, r_e=17.4726, n=1.3323, x_0=45.0000
# Sérsic 2: I_e=18.0622, r_e=1.8798, n=0.5338, x_0=51.4597
# Sérsic 3: I_e=17.2568, r_e=5.1769, n=0.8095, x_0=60.7122
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Diff_params/Halpha_fit_diff.csv", index_col=0)
initial_guesses = np.concatenate([
    df['Component 1'].values,  # [I_e, r_e, n, x_0] per Component 1
    df['Component 2'].values,  # [I_e, r_e, n, x_0] per Component 2
    df['Component 3'].values   # [I_e, r_e, n, x_0] per Component 3
])
print(df)
# Out:
#      Component 1  Component 2  Component 3
# I_e       7.2630       3.0000       1.1283
# r_e       9.7721       1.2677      18.5946
# n         1.6185       0.6720       1.4240
# x_0      38.3152      48.0000      80.2425

# %%
lower_bounds, upper_bounds = zip(*bounds_HA)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=initial_guesses, 
                                           sigma = real_errors_HA, bounds = bounds_list, maxfev= 10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.9592, r_e=16.1208, n=2.2921, x_0=38.0000
# Sérsic 2: I_e=0.9326, r_e=5.0000, n=1.4505, x_0=49.0000
# Sérsic 3: I_e=1.9342, r_e=9.8402, n=1.1210, x_0=80.0000
# [0.68393049 1.90328873 0.28627472 0.1770513  1.29820953 4.4821957
#  1.10630126 0.50545118 0.46361882 1.40058147 0.1870777  0.27872754]
# 24.06259198159703

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.2, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 5),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2),
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[0])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 37899.61458459004
# differential_evolution step 2: f(x)= 21411.848507738174
# differential_evolution step 3: f(x)= 5648.092262249735
# differential_evolution step 4: f(x)= 5520.849224077148
# differential_evolution step 5: f(x)= 2786.5982883010183
# differential_evolution step 6: f(x)= 2241.679126024233
# differential_evolution step 7: f(x)= 1152.2736509909398
# differential_evolution step 8: f(x)= 1152.2736509909398
# differential_evolution step 9: f(x)= 1152.2736509909398
# differential_evolution step 10: f(x)= 1152.2736509909398
# differential_evolution step 11: f(x)= 921.2821173211083
# differential_evolution step 12: f(x)= 921.2821173211083
# differential_evolution step 13: f(x)= 533.3966184172743
# differential_evolution step 14: f(x)= 533.3966184172743
# differential_evolution step 15: f(x)= 533.3966184172743
# differential_evolution step 16: f(x)= 533.3966184172743
# differential_evolution step 17: f(x)= 533.3966184172743
# differential_evolution step 18: f(x)= 533.3966184172743
# differential_evolution step 19: f(x)= 418.8603434970864
# differential_evolution step 20: f(x)= 309.75796004605235
# differential_evolution step 21: f(x)= 309.75796004605235
# differential_evolution step 22: f(x)= 309.75796004605235
# differential_evolution step 23: f(x)= 309.75796004605235
# differential_evolution step 24: f(x)= 309.75796004605235
# differential_evolution step 25: f(x)= 309.75796004605235
# differential_evolution step 26: f(x)= 309.75796004605235
# differential_evolution step 27: f(x)= 229.51103068884086
# differential_evolution step 28: f(x)= 229.51103068884086
# differential_evolution step 29: f(x)= 229.51103068884086
# differential_evolution step 30: f(x)= 227.94018076891587
# differential_evolution step 31: f(x)= 193.91076374865207
# differential_evolution step 32: f(x)= 193.91076374865207
# differential_evolution step 33: f(x)= 187.48319298134467
# differential_evolution step 34: f(x)= 187.48319298134467
# differential_evolution step 35: f(x)= 170.55993903066405
# differential_evolution step 36: f(x)= 152.4437639915731
# differential_evolution step 37: f(x)= 152.4437639915731
# differential_evolution step 38: f(x)= 152.4437639915731
# differential_evolution step 39: f(x)= 152.4437639915731
# differential_evolution step 40: f(x)= 131.5493912801858
# differential_evolution step 41: f(x)= 131.5493912801858
# differential_evolution step 42: f(x)= 118.69095697002658
# differential_evolution step 43: f(x)= 118.69095697002658
# differential_evolution step 44: f(x)= 118.69095697002658
# differential_evolution step 45: f(x)= 118.69095697002658
# differential_evolution step 46: f(x)= 118.69095697002658
# differential_evolution step 47: f(x)= 118.69095697002658
# differential_evolution step 48: f(x)= 118.69095697002658
# differential_evolution step 49: f(x)= 118.69095697002658
# differential_evolution step 50: f(x)= 118.69095697002658
# differential_evolution step 51: f(x)= 118.69095697002658
# differential_evolution step 52: f(x)= 118.69095697002658
# differential_evolution step 53: f(x)= 101.38908834341761
# differential_evolution step 54: f(x)= 101.38908834341761
# differential_evolution step 55: f(x)= 101.38908834341761
# differential_evolution step 56: f(x)= 101.38908834341761
# differential_evolution step 57: f(x)= 101.38908834341761
# differential_evolution step 58: f(x)= 101.38908834341761
# differential_evolution step 59: f(x)= 101.38908834341761
# differential_evolution step 60: f(x)= 101.38908834341761
# differential_evolution step 61: f(x)= 100.61895438272731
# differential_evolution step 62: f(x)= 100.61895438272731
# differential_evolution step 63: f(x)= 100.61895438272731
# differential_evolution step 64: f(x)= 100.61895438272731
# differential_evolution step 65: f(x)= 94.71546942662204
# differential_evolution step 66: f(x)= 94.71546942662204
# differential_evolution step 67: f(x)= 81.90938730903119
# differential_evolution step 68: f(x)= 81.90938730903119
# differential_evolution step 69: f(x)= 81.90938730903119
# differential_evolution step 70: f(x)= 81.90938730903119
# differential_evolution step 71: f(x)= 78.57944459805258
# differential_evolution step 72: f(x)= 78.57944459805258
# differential_evolution step 73: f(x)= 78.57944459805258
# differential_evolution step 74: f(x)= 77.8581268309269
# differential_evolution step 75: f(x)= 77.8581268309269
# differential_evolution step 76: f(x)= 76.7805473170221
# differential_evolution step 77: f(x)= 76.7805473170221
# differential_evolution step 78: f(x)= 76.7805473170221
# differential_evolution step 79: f(x)= 72.37239300758567
# differential_evolution step 80: f(x)= 72.37239300758567
# differential_evolution step 81: f(x)= 72.37239300758567
# differential_evolution step 82: f(x)= 72.37239300758567
# differential_evolution step 83: f(x)= 72.37239300758567
# differential_evolution step 84: f(x)= 72.37239300758567
# differential_evolution step 85: f(x)= 72.37239300758567
# differential_evolution step 86: f(x)= 72.37239300758567
# differential_evolution step 87: f(x)= 72.37239300758567
# differential_evolution step 88: f(x)= 72.37239300758567
# differential_evolution step 89: f(x)= 72.37239300758567
# differential_evolution step 90: f(x)= 72.37239300758567
# differential_evolution step 91: f(x)= 72.37239300758567
# differential_evolution step 92: f(x)= 72.37239300758567
# differential_evolution step 93: f(x)= 72.37239300758567
# differential_evolution step 94: f(x)= 69.45646259854797
# differential_evolution step 95: f(x)= 69.45646259854797
# differential_evolution step 96: f(x)= 69.45646259854797
# differential_evolution step 97: f(x)= 69.45646259854797
# differential_evolution step 98: f(x)= 69.45646259854797
# differential_evolution step 99: f(x)= 67.26383111641307
# differential_evolution step 100: f(x)= 67.15963050489087
# differential_evolution step 101: f(x)= 67.15963050489087
# differential_evolution step 102: f(x)= 67.15963050489087
# differential_evolution step 103: f(x)= 67.15963050489087
# differential_evolution step 104: f(x)= 67.15963050489087
# differential_evolution step 105: f(x)= 67.15963050489087
# differential_evolution step 106: f(x)= 67.15963050489087
# differential_evolution step 107: f(x)= 66.98595842153566
# differential_evolution step 108: f(x)= 66.98595842153566
# differential_evolution step 109: f(x)= 66.98595842153566
# differential_evolution step 110: f(x)= 66.98595842153566
# differential_evolution step 111: f(x)= 66.98595842153566
# differential_evolution step 112: f(x)= 66.98595842153566
# differential_evolution step 113: f(x)= 66.98595842153566
# differential_evolution step 114: f(x)= 66.98595842153566
# differential_evolution step 115: f(x)= 66.98595842153566
# differential_evolution step 116: f(x)= 66.98595842153566
# differential_evolution step 117: f(x)= 65.92098917739311
# differential_evolution step 118: f(x)= 65.92098917739311
# differential_evolution step 119: f(x)= 65.92098917739311
# differential_evolution step 120: f(x)= 65.92098917739311
# differential_evolution step 121: f(x)= 65.92098917739311
# differential_evolution step 122: f(x)= 65.92098917739311
# differential_evolution step 123: f(x)= 65.57545395941756
# differential_evolution step 124: f(x)= 65.57545395941756
# differential_evolution step 125: f(x)= 65.57545395941756
# differential_evolution step 126: f(x)= 65.39945726702716
# differential_evolution step 127: f(x)= 65.39945726702716
# differential_evolution step 128: f(x)= 65.39945726702716
# differential_evolution step 129: f(x)= 65.39945726702716
# differential_evolution step 130: f(x)= 64.73757582125934
# differential_evolution step 131: f(x)= 64.73757582125934
# differential_evolution step 132: f(x)= 64.0607485023494
# differential_evolution step 133: f(x)= 61.9832806063949
# differential_evolution step 134: f(x)= 61.9832806063949
# differential_evolution step 135: f(x)= 61.9832806063949
# differential_evolution step 136: f(x)= 61.9832806063949
# differential_evolution step 137: f(x)= 61.9832806063949
# differential_evolution step 138: f(x)= 61.9832806063949
# differential_evolution step 139: f(x)= 61.9832806063949
# differential_evolution step 140: f(x)= 61.9832806063949
# differential_evolution step 141: f(x)= 61.9832806063949
# differential_evolution step 142: f(x)= 61.9832806063949
# differential_evolution step 143: f(x)= 61.9832806063949
# differential_evolution step 144: f(x)= 61.9832806063949
# differential_evolution step 145: f(x)= 61.9832806063949
# differential_evolution step 146: f(x)= 61.9832806063949
# differential_evolution step 147: f(x)= 61.9832806063949
# differential_evolution step 148: f(x)= 61.9832806063949
# differential_evolution step 149: f(x)= 61.9832806063949
# differential_evolution step 150: f(x)= 61.9832806063949
# differential_evolution step 151: f(x)= 60.15123777485879
# differential_evolution step 152: f(x)= 60.15123777485879
# differential_evolution step 153: f(x)= 60.15123777485879
# differential_evolution step 154: f(x)= 60.15123777485879
# differential_evolution step 155: f(x)= 60.15123777485879
# differential_evolution step 156: f(x)= 60.15123777485879
# differential_evolution step 157: f(x)= 60.15123777485879
# differential_evolution step 158: f(x)= 59.913696507922396
# differential_evolution step 159: f(x)= 59.913696507922396
# differential_evolution step 160: f(x)= 59.913696507922396
# differential_evolution step 161: f(x)= 59.913696507922396
# differential_evolution step 162: f(x)= 59.913696507922396
# differential_evolution step 163: f(x)= 59.913696507922396
# differential_evolution step 164: f(x)= 59.913696507922396
# differential_evolution step 165: f(x)= 59.913696507922396
# differential_evolution step 166: f(x)= 59.913696507922396
# differential_evolution step 167: f(x)= 59.913696507922396
# differential_evolution step 168: f(x)= 59.913696507922396
# differential_evolution step 169: f(x)= 59.913696507922396
# differential_evolution step 170: f(x)= 59.913696507922396
# differential_evolution step 171: f(x)= 59.913696507922396
# differential_evolution step 172: f(x)= 59.913696507922396
# differential_evolution step 173: f(x)= 59.913696507922396
# differential_evolution step 174: f(x)= 59.913696507922396
# differential_evolution step 175: f(x)= 59.913696507922396
# differential_evolution step 176: f(x)= 59.913696507922396
# differential_evolution step 177: f(x)= 59.913696507922396
# differential_evolution step 178: f(x)= 59.913696507922396
# differential_evolution step 179: f(x)= 59.913696507922396
# differential_evolution step 180: f(x)= 59.913696507922396
# differential_evolution step 181: f(x)= 59.913696507922396
# differential_evolution step 182: f(x)= 59.913696507922396
# differential_evolution step 183: f(x)= 59.913696507922396
# differential_evolution step 184: f(x)= 59.913696507922396
# differential_evolution step 185: f(x)= 59.913696507922396
# differential_evolution step 186: f(x)= 59.913696507922396
# differential_evolution step 187: f(x)= 57.814932937275444
# differential_evolution step 188: f(x)= 57.814932937275444
# differential_evolution step 189: f(x)= 57.814932937275444
# differential_evolution step 190: f(x)= 57.814932937275444
# differential_evolution step 191: f(x)= 57.814932937275444
# differential_evolution step 192: f(x)= 57.814932937275444
# differential_evolution step 193: f(x)= 57.814932937275444
# differential_evolution step 194: f(x)= 57.814932937275444
# differential_evolution step 195: f(x)= 57.814932937275444
# differential_evolution step 196: f(x)= 57.814932937275444
# differential_evolution step 197: f(x)= 57.814932937275444
# differential_evolution step 198: f(x)= 56.77008139731361
# differential_evolution step 199: f(x)= 56.77008139731361
# differential_evolution step 200: f(x)= 56.77008139731361
# differential_evolution step 201: f(x)= 56.77008139731361
# differential_evolution step 202: f(x)= 56.77008139731361
# differential_evolution step 203: f(x)= 56.77008139731361
# differential_evolution step 204: f(x)= 56.77008139731361
# differential_evolution step 205: f(x)= 56.77008139731361
# differential_evolution step 206: f(x)= 56.77008139731361
# differential_evolution step 207: f(x)= 56.77008139731361
# differential_evolution step 208: f(x)= 56.77008139731361
# differential_evolution step 209: f(x)= 56.77008139731361
# differential_evolution step 210: f(x)= 56.77008139731361
# differential_evolution step 211: f(x)= 56.77008139731361
# differential_evolution step 212: f(x)= 56.77008139731361
# differential_evolution step 213: f(x)= 56.77008139731361
# differential_evolution step 214: f(x)= 56.77008139731361
# differential_evolution step 215: f(x)= 56.77008139731361
# differential_evolution step 216: f(x)= 56.77008139731361
# differential_evolution step 217: f(x)= 56.77008139731361
# differential_evolution step 218: f(x)= 56.77008139731361
# differential_evolution step 219: f(x)= 56.77008139731361
# differential_evolution step 220: f(x)= 56.77008139731361
# differential_evolution step 221: f(x)= 56.05574060960152
# differential_evolution step 222: f(x)= 56.05574060960152
# differential_evolution step 223: f(x)= 56.03242026225866
# differential_evolution step 224: f(x)= 55.839527517403496
# differential_evolution step 225: f(x)= 55.839527517403496
# differential_evolution step 226: f(x)= 55.839527517403496
# differential_evolution step 227: f(x)= 55.839527517403496
# differential_evolution step 228: f(x)= 55.06070772174431
# differential_evolution step 229: f(x)= 55.06070772174431
# differential_evolution step 230: f(x)= 55.06070772174431
# differential_evolution step 231: f(x)= 55.06070772174431
# differential_evolution step 232: f(x)= 55.06070772174431
# differential_evolution step 233: f(x)= 55.06070772174431
# differential_evolution step 234: f(x)= 55.06070772174431
# differential_evolution step 235: f(x)= 55.06070772174431
# differential_evolution step 236: f(x)= 55.06070772174431
# differential_evolution step 237: f(x)= 55.06070772174431
# differential_evolution step 238: f(x)= 55.06070772174431
# differential_evolution step 239: f(x)= 55.06070772174431
# differential_evolution step 240: f(x)= 55.06070772174431
# differential_evolution step 241: f(x)= 55.06070772174431
# differential_evolution step 242: f(x)= 55.06070772174431
# differential_evolution step 243: f(x)= 54.90108199484807
# differential_evolution step 244: f(x)= 54.59614873272443
# differential_evolution step 245: f(x)= 54.59614873272443
# differential_evolution step 246: f(x)= 54.59614873272443
# differential_evolution step 247: f(x)= 54.59614873272443
# differential_evolution step 248: f(x)= 54.59614873272443
# differential_evolution step 249: f(x)= 54.59614873272443
# differential_evolution step 250: f(x)= 54.59614873272443
# differential_evolution step 251: f(x)= 54.59614873272443
# differential_evolution step 252: f(x)= 54.11847470679438
# differential_evolution step 253: f(x)= 54.11847470679438
# differential_evolution step 254: f(x)= 54.11847470679438
# differential_evolution step 255: f(x)= 54.11847470679438
# differential_evolution step 256: f(x)= 54.11847470679438
# differential_evolution step 257: f(x)= 53.73425410541909
# differential_evolution step 258: f(x)= 53.73425410541909
# differential_evolution step 259: f(x)= 53.73425410541909
# differential_evolution step 260: f(x)= 53.73425410541909
# differential_evolution step 261: f(x)= 53.73425410541909
# differential_evolution step 262: f(x)= 53.73425410541909
# differential_evolution step 263: f(x)= 53.73425410541909
# differential_evolution step 264: f(x)= 53.47781964790282
# differential_evolution step 265: f(x)= 53.47781964790282
# differential_evolution step 266: f(x)= 53.47781964790282
# differential_evolution step 267: f(x)= 53.47781964790282
# differential_evolution step 268: f(x)= 53.47781964790282
# differential_evolution step 269: f(x)= 53.47781964790282
# differential_evolution step 270: f(x)= 53.47781964790282
# differential_evolution step 271: f(x)= 53.47781964790282
# differential_evolution step 272: f(x)= 53.47781964790282
# differential_evolution step 273: f(x)= 53.47781964790282
# differential_evolution step 274: f(x)= 53.45726522968706
# differential_evolution step 275: f(x)= 53.45726522968706
# differential_evolution step 276: f(x)= 53.45599077915015
# differential_evolution step 277: f(x)= 53.37572894046129
# differential_evolution step 278: f(x)= 53.37572894046129
# differential_evolution step 279: f(x)= 53.37572894046129
# differential_evolution step 280: f(x)= 53.1812208822064
# differential_evolution step 281: f(x)= 53.1812208822064
# differential_evolution step 282: f(x)= 53.1812208822064
# differential_evolution step 283: f(x)= 53.1812208822064
# differential_evolution step 284: f(x)= 52.96290928304439
# differential_evolution step 285: f(x)= 52.96290928304439
# differential_evolution step 286: f(x)= 52.96290928304439
# differential_evolution step 287: f(x)= 52.96290928304439
# differential_evolution step 288: f(x)= 52.96290928304439
# differential_evolution step 289: f(x)= 52.96290928304439
# differential_evolution step 290: f(x)= 52.96290928304439
# differential_evolution step 291: f(x)= 52.90161829122331
# differential_evolution step 292: f(x)= 52.90161829122331
# differential_evolution step 293: f(x)= 52.90161829122331
# differential_evolution step 294: f(x)= 52.692188529328135
# differential_evolution step 295: f(x)= 52.692188529328135
# differential_evolution step 296: f(x)= 52.692188529328135
# differential_evolution step 297: f(x)= 52.692188529328135
# differential_evolution step 298: f(x)= 52.692188529328135
# differential_evolution step 299: f(x)= 52.692188529328135
# differential_evolution step 300: f(x)= 52.692188529328135
# differential_evolution step 301: f(x)= 52.692188529328135
# differential_evolution step 302: f(x)= 52.692188529328135
# differential_evolution step 303: f(x)= 52.692188529328135
# differential_evolution step 304: f(x)= 52.692188529328135
# differential_evolution step 305: f(x)= 52.692188529328135
# differential_evolution step 306: f(x)= 52.692188529328135
# differential_evolution step 307: f(x)= 52.692188529328135
# differential_evolution step 308: f(x)= 52.67990811363727
# differential_evolution step 309: f(x)= 52.67990811363727
# differential_evolution step 310: f(x)= 52.66386538809511
# differential_evolution step 311: f(x)= 52.66386538809511
# differential_evolution step 312: f(x)= 52.66386538809511
# differential_evolution step 313: f(x)= 52.66386538809511
# differential_evolution step 314: f(x)= 52.66386538809511
# differential_evolution step 315: f(x)= 52.66386538809511
# differential_evolution step 316: f(x)= 52.624086091652764
# differential_evolution step 317: f(x)= 52.52850083064703
# differential_evolution step 318: f(x)= 52.52850083064703
# differential_evolution step 319: f(x)= 52.52850083064703
# differential_evolution step 320: f(x)= 52.52850083064703
# differential_evolution step 321: f(x)= 52.52850083064703
# differential_evolution step 322: f(x)= 52.52850083064703
# differential_evolution step 323: f(x)= 52.52850083064703
# differential_evolution step 324: f(x)= 52.49858270413479
# differential_evolution step 325: f(x)= 52.49858270413479
# differential_evolution step 326: f(x)= 52.49858270413479
# differential_evolution step 327: f(x)= 52.49858270413479
# differential_evolution step 328: f(x)= 52.46112560603812
# differential_evolution step 329: f(x)= 52.46112560603812
# differential_evolution step 330: f(x)= 52.36679055184243
# differential_evolution step 331: f(x)= 52.36679055184243
# differential_evolution step 332: f(x)= 52.36679055184243
# differential_evolution step 333: f(x)= 52.36679055184243
# differential_evolution step 334: f(x)= 52.36679055184243
# differential_evolution step 335: f(x)= 52.36679055184243
# differential_evolution step 336: f(x)= 52.36679055184243
# differential_evolution step 337: f(x)= 52.36679055184243
# differential_evolution step 338: f(x)= 52.36679055184243
# differential_evolution step 339: f(x)= 52.36679055184243
# differential_evolution step 340: f(x)= 52.36679055184243
# differential_evolution step 341: f(x)= 52.361860654621864
# differential_evolution step 342: f(x)= 52.361860654621864
# differential_evolution step 343: f(x)= 52.361860654621864
# differential_evolution step 344: f(x)= 52.361860654621864
# differential_evolution step 345: f(x)= 52.33195083372123
# differential_evolution step 346: f(x)= 52.33195083372123
# differential_evolution step 347: f(x)= 52.33195083372123
# differential_evolution step 348: f(x)= 52.33195083372123
# differential_evolution step 349: f(x)= 52.33195083372123
# differential_evolution step 350: f(x)= 52.33195083372123
# differential_evolution step 351: f(x)= 52.31084454677678
# differential_evolution step 352: f(x)= 52.31084454677678
# differential_evolution step 353: f(x)= 52.31084454677678
# differential_evolution step 354: f(x)= 52.184813880654495
# differential_evolution step 355: f(x)= 52.184813880654495
# differential_evolution step 356: f(x)= 52.184813880654495
# differential_evolution step 357: f(x)= 52.184813880654495
# differential_evolution step 358: f(x)= 52.184813880654495
# differential_evolution step 359: f(x)= 52.184813880654495
# differential_evolution step 360: f(x)= 52.184813880654495
# differential_evolution step 361: f(x)= 52.184813880654495
# differential_evolution step 362: f(x)= 52.184813880654495
# differential_evolution step 363: f(x)= 52.184813880654495
# differential_evolution step 364: f(x)= 52.184813880654495
# differential_evolution step 365: f(x)= 52.184813880654495
# differential_evolution step 366: f(x)= 52.184813880654495
# differential_evolution step 367: f(x)= 52.184813880654495
# differential_evolution step 368: f(x)= 52.184813880654495
# differential_evolution step 369: f(x)= 52.184813880654495
# differential_evolution step 370: f(x)= 52.162892852546555
# differential_evolution step 371: f(x)= 52.162892852546555
# differential_evolution step 372: f(x)= 52.162892852546555
# differential_evolution step 373: f(x)= 52.162892852546555
# differential_evolution step 374: f(x)= 52.162892852546555
# differential_evolution step 375: f(x)= 52.162892852546555
# differential_evolution step 376: f(x)= 52.13555098086502
# differential_evolution step 377: f(x)= 52.13555098086502
# differential_evolution step 378: f(x)= 52.13555098086502
# differential_evolution step 379: f(x)= 52.13555098086502
# differential_evolution step 380: f(x)= 52.13555098086502
# differential_evolution step 381: f(x)= 52.13555098086502
# differential_evolution step 382: f(x)= 52.13555098086502
# differential_evolution step 383: f(x)= 52.13555098086502
# differential_evolution step 384: f(x)= 52.125503419306696
# differential_evolution step 385: f(x)= 52.125503419306696
# differential_evolution step 386: f(x)= 52.125503419306696
# differential_evolution step 387: f(x)= 52.125503419306696
# differential_evolution step 388: f(x)= 52.125503419306696
# differential_evolution step 389: f(x)= 52.125503419306696
# differential_evolution step 390: f(x)= 52.125503419306696
# differential_evolution step 391: f(x)= 52.125503419306696
# differential_evolution step 392: f(x)= 52.10757710207738
# differential_evolution step 393: f(x)= 52.10757710207738
# differential_evolution step 394: f(x)= 52.10757710207738
# differential_evolution step 395: f(x)= 52.10757710207738
# differential_evolution step 396: f(x)= 52.10757710207738
# differential_evolution step 397: f(x)= 52.10757710207738
# differential_evolution step 398: f(x)= 52.10757710207738
# differential_evolution step 399: f(x)= 52.10757710207738
# differential_evolution step 400: f(x)= 52.10757710207738
# differential_evolution step 401: f(x)= 52.10757710207738
# differential_evolution step 402: f(x)= 52.10757710207738
# differential_evolution step 403: f(x)= 52.10757710207738
# differential_evolution step 404: f(x)= 52.10757710207738
# differential_evolution step 405: f(x)= 52.10757710207738
# differential_evolution step 406: f(x)= 52.10757710207738
# differential_evolution step 407: f(x)= 52.10757710207738
# differential_evolution step 408: f(x)= 52.10757710207738
# differential_evolution step 409: f(x)= 52.10757710207738
# differential_evolution step 410: f(x)= 52.10757710207738
# differential_evolution step 411: f(x)= 52.10672074961241
# differential_evolution step 412: f(x)= 52.10672074961241
# differential_evolution step 413: f(x)= 52.10672074961241
# differential_evolution step 414: f(x)= 52.10672074961241
# differential_evolution step 415: f(x)= 52.10672074961241
# differential_evolution step 416: f(x)= 52.10672074961241
# differential_evolution step 417: f(x)= 52.10672074961241
# differential_evolution step 418: f(x)= 52.10672074961241
# differential_evolution step 419: f(x)= 52.10672074961241
# differential_evolution step 420: f(x)= 52.08665143805413
# differential_evolution step 421: f(x)= 52.08665143805413
# differential_evolution step 422: f(x)= 52.08665143805413
# differential_evolution step 423: f(x)= 52.08665143805413
# differential_evolution step 424: f(x)= 52.08665143805413
# differential_evolution step 425: f(x)= 52.08665143805413
# differential_evolution step 426: f(x)= 52.08665143805413
# differential_evolution step 427: f(x)= 52.08665143805413
# differential_evolution step 428: f(x)= 52.08665143805413
# differential_evolution step 429: f(x)= 52.08665143805413
# differential_evolution step 430: f(x)= 52.08665143805413
# differential_evolution step 431: f(x)= 52.08665143805413
# differential_evolution step 432: f(x)= 52.07008041349642
# differential_evolution step 433: f(x)= 52.07008041349642
# differential_evolution step 434: f(x)= 52.07008041349642
# differential_evolution step 435: f(x)= 52.07008041349642
# differential_evolution step 436: f(x)= 52.07008041349642
# differential_evolution step 437: f(x)= 52.07008041349642
# differential_evolution step 438: f(x)= 52.06343110797411
# differential_evolution step 439: f(x)= 52.06343110797411
# differential_evolution step 440: f(x)= 52.06343110797411
# differential_evolution step 441: f(x)= 52.060168297097405
# differential_evolution step 442: f(x)= 52.060168297097405
# differential_evolution step 443: f(x)= 52.060168297097405
# differential_evolution step 444: f(x)= 52.060168297097405
# differential_evolution step 445: f(x)= 52.060168297097405
# differential_evolution step 446: f(x)= 52.060168297097405
# differential_evolution step 447: f(x)= 52.060168297097405
# differential_evolution step 448: f(x)= 52.060168297097405
# differential_evolution step 449: f(x)= 52.060168297097405
# differential_evolution step 450: f(x)= 52.04923799839323
# differential_evolution step 451: f(x)= 52.04923799839323
# differential_evolution step 452: f(x)= 52.04923799839323
# differential_evolution step 453: f(x)= 52.04923799839323
# differential_evolution step 454: f(x)= 52.04923799839323
# differential_evolution step 455: f(x)= 52.04923799839323
# differential_evolution step 456: f(x)= 52.04923799839323
# differential_evolution step 457: f(x)= 52.04923799839323
# differential_evolution step 458: f(x)= 52.04317500087032
# differential_evolution step 459: f(x)= 52.04317500087032
# differential_evolution step 460: f(x)= 52.04317500087032
# differential_evolution step 461: f(x)= 52.04317500087032
# differential_evolution step 462: f(x)= 52.04317500087032
# differential_evolution step 463: f(x)= 52.04317500087032
# differential_evolution step 464: f(x)= 52.04317500087032
# differential_evolution step 465: f(x)= 52.04317500087032
# differential_evolution step 466: f(x)= 52.04317500087032
# differential_evolution step 467: f(x)= 52.04317500087032
# differential_evolution step 468: f(x)= 52.04317500087032
# differential_evolution step 469: f(x)= 52.04317500087032
# differential_evolution step 470: f(x)= 52.04317500087032
# differential_evolution step 471: f(x)= 52.04317500087032
# differential_evolution step 472: f(x)= 52.04317500087032
# differential_evolution step 473: f(x)= 52.04260693781334
# differential_evolution step 474: f(x)= 52.04260693781334
# differential_evolution step 475: f(x)= 52.04260693781334
# differential_evolution step 476: f(x)= 52.04260693781334
# differential_evolution step 477: f(x)= 52.0424478976052
# differential_evolution step 478: f(x)= 52.0424478976052
# differential_evolution step 479: f(x)= 52.0424478976052
# differential_evolution step 480: f(x)= 52.0424478976052
# differential_evolution step 481: f(x)= 52.0424478976052
# differential_evolution step 482: f(x)= 52.0424478976052
# differential_evolution step 483: f(x)= 52.036964687270036
# differential_evolution step 484: f(x)= 52.036964687270036
# differential_evolution step 485: f(x)= 52.036964687270036
# differential_evolution step 486: f(x)= 52.036964687270036
# differential_evolution step 487: f(x)= 52.036964687270036
# differential_evolution step 488: f(x)= 52.036964687270036
# differential_evolution step 489: f(x)= 52.036964687270036
# differential_evolution step 490: f(x)= 52.036964687270036
# differential_evolution step 491: f(x)= 52.036964687270036
# differential_evolution step 492: f(x)= 52.03303788306181
# differential_evolution step 493: f(x)= 52.03303788306181
# differential_evolution step 494: f(x)= 52.03303788306181
# differential_evolution step 495: f(x)= 52.03303788306181
# differential_evolution step 496: f(x)= 52.03303788306181
# differential_evolution step 497: f(x)= 52.03303788306181
# differential_evolution step 498: f(x)= 52.03303788306181
# differential_evolution step 499: f(x)= 52.03303788306181
# differential_evolution step 500: f(x)= 52.03303788306181
# differential_evolution step 501: f(x)= 52.03303788306181
# differential_evolution step 502: f(x)= 52.03303788306181
# differential_evolution step 503: f(x)= 52.03303788306181
# differential_evolution step 504: f(x)= 52.03303788306181
# differential_evolution step 505: f(x)= 52.03303788306181
# differential_evolution step 506: f(x)= 52.03303788306181
# differential_evolution step 507: f(x)= 52.03303788306181
# differential_evolution step 508: f(x)= 52.03303788306181
# differential_evolution step 509: f(x)= 52.03303788306181
# differential_evolution step 510: f(x)= 52.03303788306181
# differential_evolution step 511: f(x)= 52.03303788306181
# differential_evolution step 512: f(x)= 52.03303788306181
# differential_evolution step 513: f(x)= 52.03303788306181
# differential_evolution step 514: f(x)= 52.03303788306181
# differential_evolution step 515: f(x)= 52.03303788306181
# differential_evolution step 516: f(x)= 52.03303788306181
# differential_evolution step 517: f(x)= 52.03303788306181
# differential_evolution step 518: f(x)= 52.03303788306181
# differential_evolution step 519: f(x)= 52.03303788306181
# differential_evolution step 520: f(x)= 52.03269108318117
# differential_evolution step 521: f(x)= 52.03269108318117
# differential_evolution step 522: f(x)= 52.03269108318117
# differential_evolution step 523: f(x)= 52.03269108318117
# differential_evolution step 524: f(x)= 52.03269108318117
# differential_evolution step 525: f(x)= 52.03269108318117
# differential_evolution step 526: f(x)= 52.03269108318117
# differential_evolution step 527: f(x)= 52.0320441087803
# differential_evolution step 528: f(x)= 52.0320441087803
# differential_evolution step 529: f(x)= 52.0320441087803
# differential_evolution step 530: f(x)= 52.0320441087803
# differential_evolution step 531: f(x)= 52.03014840650005
# differential_evolution step 532: f(x)= 52.03014840650005
# differential_evolution step 533: f(x)= 52.03014840650005
# differential_evolution step 534: f(x)= 52.03014840650005
# differential_evolution step 535: f(x)= 52.03014840650005
# differential_evolution step 536: f(x)= 52.03014840650005
# differential_evolution step 537: f(x)= 52.03014840650005
# differential_evolution step 538: f(x)= 52.03014840650005
# differential_evolution step 539: f(x)= 52.03014840650005
# differential_evolution step 540: f(x)= 52.03014840650005
# differential_evolution step 541: f(x)= 52.03014840650005
# differential_evolution step 542: f(x)= 52.03014840650005
# differential_evolution step 543: f(x)= 52.03014840650005
# differential_evolution step 544: f(x)= 52.03014840650005
# differential_evolution step 545: f(x)= 52.03014840650005
# differential_evolution step 546: f(x)= 52.03014840650005
# differential_evolution step 547: f(x)= 52.02983046130801
# differential_evolution step 548: f(x)= 52.02983046130801
# differential_evolution step 549: f(x)= 52.0293441625021
# differential_evolution step 550: f(x)= 52.02741254838264
# differential_evolution step 551: f(x)= 52.02741254838264
# differential_evolution step 552: f(x)= 52.02741254838264
# differential_evolution step 553: f(x)= 52.02741254838264
# differential_evolution step 554: f(x)= 52.02741254838264
# differential_evolution step 555: f(x)= 52.02741254838264
# differential_evolution step 556: f(x)= 52.02741254838264
# differential_evolution step 557: f(x)= 52.02741254838264
# differential_evolution step 558: f(x)= 52.02741254838264
# differential_evolution step 559: f(x)= 52.02741254838264
# differential_evolution step 560: f(x)= 52.02741254838264
# differential_evolution step 561: f(x)= 52.02741254838264
# differential_evolution step 562: f(x)= 52.02741254838264
# differential_evolution step 563: f(x)= 52.02741254838264
# differential_evolution step 564: f(x)= 52.02741254838264
# differential_evolution step 565: f(x)= 52.02741254838264
# differential_evolution step 566: f(x)= 52.02741254838264
# differential_evolution step 567: f(x)= 52.02741254838264
# differential_evolution step 568: f(x)= 52.02741254838264
# differential_evolution step 569: f(x)= 52.02741254838264
# differential_evolution step 570: f(x)= 52.02741254838264
# differential_evolution step 571: f(x)= 52.02741254838264
# differential_evolution step 572: f(x)= 52.02741254838264
# differential_evolution step 573: f(x)= 52.02741254838264
# differential_evolution step 574: f(x)= 52.02741254838264
# differential_evolution step 575: f(x)= 52.02741254838264
# differential_evolution step 576: f(x)= 52.02741254838264
# differential_evolution step 577: f(x)= 52.02741254838264
# differential_evolution step 578: f(x)= 52.02741254838264
# differential_evolution step 579: f(x)= 52.02741254838264
# differential_evolution step 580: f(x)= 52.02741254838264
# differential_evolution step 581: f(x)= 52.02741254838264
# differential_evolution step 582: f(x)= 52.02741254838264
# differential_evolution step 583: f(x)= 52.02741254838264
# differential_evolution step 584: f(x)= 52.02741254838264
# differential_evolution step 585: f(x)= 52.027166260622124
# differential_evolution step 586: f(x)= 52.02703066910264
# differential_evolution step 587: f(x)= 52.02703066910264
# differential_evolution step 588: f(x)= 52.02703066910264
# differential_evolution step 589: f(x)= 52.02703066910264
# differential_evolution step 590: f(x)= 52.02703066910264
# differential_evolution step 591: f(x)= 52.02703066910264
# differential_evolution step 592: f(x)= 52.02703066910264
# differential_evolution step 593: f(x)= 52.02703066910264
# differential_evolution step 594: f(x)= 52.02703066910264
# differential_evolution step 595: f(x)= 52.026662500895334
# differential_evolution step 596: f(x)= 52.026662500895334
# differential_evolution step 597: f(x)= 52.026662500895334
# differential_evolution step 598: f(x)= 52.026662500895334
# differential_evolution step 599: f(x)= 52.02646284638829
# differential_evolution step 600: f(x)= 52.02646284638829
# differential_evolution step 601: f(x)= 52.02646284638829
# differential_evolution step 602: f(x)= 52.02646284638829
# differential_evolution step 603: f(x)= 52.02642283967865
# differential_evolution step 604: f(x)= 52.02642283967865
# differential_evolution step 605: f(x)= 52.02603622118234
# differential_evolution step 606: f(x)= 52.02603622118234
# differential_evolution step 607: f(x)= 52.02603622118234
# differential_evolution step 608: f(x)= 52.02603622118234
# differential_evolution step 609: f(x)= 52.02603622118234
# differential_evolution step 610: f(x)= 52.02603622118234
# differential_evolution step 611: f(x)= 52.02603622118234
# differential_evolution step 612: f(x)= 52.02603622118234
# differential_evolution step 613: f(x)= 52.02603622118234
# differential_evolution step 614: f(x)= 52.02603622118234
# differential_evolution step 615: f(x)= 52.02603622118234
# differential_evolution step 616: f(x)= 52.02603622118234
# differential_evolution step 617: f(x)= 52.02603622118234
# differential_evolution step 618: f(x)= 52.02603622118234
# differential_evolution step 619: f(x)= 52.02603622118234
# differential_evolution step 620: f(x)= 52.02603622118234
# differential_evolution step 621: f(x)= 52.0256680909823
# differential_evolution step 622: f(x)= 52.0256680909823
# differential_evolution step 623: f(x)= 52.0256680909823
# differential_evolution step 624: f(x)= 52.02545029341286
# differential_evolution step 625: f(x)= 52.02545029341286
# differential_evolution step 626: f(x)= 52.02545029341286
# differential_evolution step 627: f(x)= 52.02545029341286
# differential_evolution step 628: f(x)= 52.02545029341286
# differential_evolution step 629: f(x)= 52.02545029341286
# differential_evolution step 630: f(x)= 52.02545029341286
# differential_evolution step 631: f(x)= 52.02545029341286
# differential_evolution step 632: f(x)= 52.02545029341286
# differential_evolution step 633: f(x)= 52.02545029341286
# differential_evolution step 634: f(x)= 52.02545029341286
# differential_evolution step 635: f(x)= 52.02545029341286
# differential_evolution step 636: f(x)= 52.02545029341286
# differential_evolution step 637: f(x)= 52.02545029341286
# differential_evolution step 638: f(x)= 52.02545029341286
# differential_evolution step 639: f(x)= 52.02545029341286
# differential_evolution step 640: f(x)= 52.02545029341286
# differential_evolution step 641: f(x)= 52.02545029341286
# differential_evolution step 642: f(x)= 52.02545029341286
# differential_evolution step 643: f(x)= 52.02545029341286
# differential_evolution step 644: f(x)= 52.02545029341286
# differential_evolution step 645: f(x)= 52.02545029341286
# differential_evolution step 646: f(x)= 52.02545029341286
# differential_evolution step 647: f(x)= 52.02545029341286
# differential_evolution step 648: f(x)= 52.02545029341286
# differential_evolution step 649: f(x)= 52.02545029341286
# differential_evolution step 650: f(x)= 52.02545029341286
# differential_evolution step 651: f(x)= 52.02545029341286
# differential_evolution step 652: f(x)= 52.02545029341286
# differential_evolution step 653: f(x)= 52.02545029341286
# differential_evolution step 654: f(x)= 52.02545029341286
# differential_evolution step 655: f(x)= 52.02545029341286
# differential_evolution step 656: f(x)= 52.02545029341286
# differential_evolution step 657: f(x)= 52.02545029341286
# differential_evolution step 658: f(x)= 52.02545029341286
# differential_evolution step 659: f(x)= 52.02545029341286
# differential_evolution step 660: f(x)= 52.02545029341286
# differential_evolution step 661: f(x)= 52.02545029341286
# differential_evolution step 662: f(x)= 52.02542693736209
# differential_evolution step 663: f(x)= 52.02542693736209
# differential_evolution step 664: f(x)= 52.02542693736209
# differential_evolution step 665: f(x)= 52.02533137641135
# differential_evolution step 666: f(x)= 52.02533137641135
# differential_evolution step 667: f(x)= 52.02533137641135
# differential_evolution step 668: f(x)= 52.02533137641135
# differential_evolution step 669: f(x)= 52.02533137641135
# differential_evolution step 670: f(x)= 52.02533137641135
# differential_evolution step 671: f(x)= 52.02533137641135
# differential_evolution step 672: f(x)= 52.02533137641135
# differential_evolution step 673: f(x)= 52.02533137641135
# differential_evolution step 674: f(x)= 52.02533137641135
# differential_evolution step 675: f(x)= 52.02533137641135
# differential_evolution step 676: f(x)= 52.02533137641135
# differential_evolution step 677: f(x)= 52.025299578162596
# differential_evolution step 678: f(x)= 52.025299578162596
# differential_evolution step 679: f(x)= 52.025299578162596
# differential_evolution step 680: f(x)= 52.025299578162596
# differential_evolution step 681: f(x)= 52.025299578162596
# differential_evolution step 682: f(x)= 52.025299578162596
# differential_evolution step 683: f(x)= 52.025299578162596
# differential_evolution step 684: f(x)= 52.025299578162596
# differential_evolution step 685: f(x)= 52.025299578162596
# differential_evolution step 686: f(x)= 52.025286258570056
# differential_evolution step 687: f(x)= 52.025286258570056
# differential_evolution step 688: f(x)= 52.025286258570056
# differential_evolution step 689: f(x)= 52.025286258570056
# differential_evolution step 690: f(x)= 52.025286258570056
# differential_evolution step 691: f(x)= 52.025286258570056
# differential_evolution step 692: f(x)= 52.025286258570056
# differential_evolution step 693: f(x)= 52.025286258570056
# differential_evolution step 694: f(x)= 52.025286258570056
# differential_evolution step 695: f(x)= 52.025286258570056
# differential_evolution step 696: f(x)= 52.025286258570056
# differential_evolution step 697: f(x)= 52.025286258570056
# differential_evolution step 698: f(x)= 52.025286258570056
# differential_evolution step 699: f(x)= 52.025286258570056
# differential_evolution step 700: f(x)= 52.025286258570056
# differential_evolution step 701: f(x)= 52.025286258570056
# differential_evolution step 702: f(x)= 52.025286258570056
# differential_evolution step 703: f(x)= 52.025286258570056
# differential_evolution step 704: f(x)= 52.02528099876861
# differential_evolution step 705: f(x)= 52.02528099876861
# differential_evolution step 706: f(x)= 52.02528099876861
# differential_evolution step 707: f(x)= 52.02528099876861
# differential_evolution step 708: f(x)= 52.02528099876861
# differential_evolution step 709: f(x)= 52.025175109310226
# differential_evolution step 710: f(x)= 52.025175109310226
# differential_evolution step 711: f(x)= 52.025175109310226
# differential_evolution step 712: f(x)= 52.025175109310226
# differential_evolution step 713: f(x)= 52.025175109310226
# differential_evolution step 714: f(x)= 52.025175109310226
# differential_evolution step 715: f(x)= 52.025175109310226
# differential_evolution step 716: f(x)= 52.025175109310226
# differential_evolution step 717: f(x)= 52.025175109310226
# differential_evolution step 718: f(x)= 52.025175109310226
# differential_evolution step 719: f(x)= 52.025175109310226
# differential_evolution step 720: f(x)= 52.025175109310226
# differential_evolution step 721: f(x)= 52.025175109310226
# differential_evolution step 722: f(x)= 52.025175109310226
# differential_evolution step 723: f(x)= 52.025175109310226
# differential_evolution step 724: f(x)= 52.025175109310226
# differential_evolution step 725: f(x)= 52.025175109310226
# differential_evolution step 726: f(x)= 52.025175109310226
# differential_evolution step 727: f(x)= 52.025175109310226
# differential_evolution step 728: f(x)= 52.025175109310226
# differential_evolution step 729: f(x)= 52.025175109310226
# differential_evolution step 730: f(x)= 52.025175109310226
# differential_evolution step 731: f(x)= 52.025175109310226
# differential_evolution step 732: f(x)= 52.025175109310226
# differential_evolution step 733: f(x)= 52.025175109310226
# differential_evolution step 734: f(x)= 52.025168537264435
# differential_evolution step 735: f(x)= 52.025168537264435
# differential_evolution step 736: f(x)= 52.025168537264435
# differential_evolution step 737: f(x)= 52.025168537264435
# differential_evolution step 738: f(x)= 52.025168537264435
# differential_evolution step 739: f(x)= 52.025168537264435
# differential_evolution step 740: f(x)= 52.025168537264435
# differential_evolution step 741: f(x)= 52.025168537264435
# differential_evolution step 742: f(x)= 52.025168537264435
# differential_evolution step 743: f(x)= 52.025168537264435
# differential_evolution step 744: f(x)= 52.025168537264435
# differential_evolution step 745: f(x)= 52.025161096495
# differential_evolution step 746: f(x)= 52.0251588002491
# differential_evolution step 747: f(x)= 52.02515635740923
# differential_evolution step 748: f(x)= 52.02515635740923
# differential_evolution step 749: f(x)= 52.02515635740923
# differential_evolution step 750: f(x)= 52.02515635740923
# differential_evolution step 751: f(x)= 52.025130637338165
# differential_evolution step 752: f(x)= 52.025130637338165
# differential_evolution step 753: f(x)= 52.025130637338165
# differential_evolution step 754: f(x)= 52.025130637338165
# differential_evolution step 755: f(x)= 52.025130637338165
# differential_evolution step 756: f(x)= 52.025130637338165
# differential_evolution step 757: f(x)= 52.025130637338165
# differential_evolution step 758: f(x)= 52.0251174568906
# differential_evolution step 759: f(x)= 52.0251174568906
# differential_evolution step 760: f(x)= 52.0251174568906
# differential_evolution step 761: f(x)= 52.02508722425368
# differential_evolution step 762: f(x)= 52.02508722425368
# differential_evolution step 763: f(x)= 52.02508722425368
# differential_evolution step 764: f(x)= 52.02508722425368
# differential_evolution step 765: f(x)= 52.02508722425368
# differential_evolution step 766: f(x)= 52.02508722425368
# differential_evolution step 767: f(x)= 52.02508722425368
# differential_evolution step 768: f(x)= 52.02508722425368
# differential_evolution step 769: f(x)= 52.02508722425368
# differential_evolution step 770: f(x)= 52.02508722425368
# differential_evolution step 771: f(x)= 52.02508722425368
# differential_evolution step 772: f(x)= 52.02508722425368
# differential_evolution step 773: f(x)= 52.0250790077084
# differential_evolution step 774: f(x)= 52.0250790077084
# differential_evolution step 775: f(x)= 52.0250790077084
# differential_evolution step 776: f(x)= 52.0250790077084
# differential_evolution step 777: f(x)= 52.0250790077084
# differential_evolution step 778: f(x)= 52.0250790077084
# differential_evolution step 779: f(x)= 52.0250790077084
# differential_evolution step 780: f(x)= 52.0250790077084
# differential_evolution step 781: f(x)= 52.0250790077084
# differential_evolution step 782: f(x)= 52.0250790077084
# differential_evolution step 783: f(x)= 52.02507735465531
# differential_evolution step 784: f(x)= 52.02507735465531
# differential_evolution step 785: f(x)= 52.02507735465531
# differential_evolution step 786: f(x)= 52.02507735465531
# differential_evolution step 787: f(x)= 52.02507735465531
# differential_evolution step 788: f(x)= 52.02507252316727
# differential_evolution step 789: f(x)= 52.02507252316727
# differential_evolution step 790: f(x)= 52.02507252316727
# differential_evolution step 791: f(x)= 52.025067446216894
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.9562, r_e=11.5837, n=0.4640, x_0=46.2000
# Sérsic 2: I_e=5.2719, r_e=7.7066, n=0.1000, x_0=50.3960
# Sérsic 3: I_e=4.6342, r_e=6.7353, n=0.9399, x_0=59.5613
# Chi quadro minimo: 52.02504514594374
# True

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Sérsic 1: I_e=1.9562, r_e=11.5837, n=0.4640, x_0=46.2000
# Sérsic 2: I_e=5.2719, r_e=7.7066, n=0.1000, x_0=50.3960
# Sérsic 3: I_e=4.6342, r_e=6.7353, n=0.9399, x_0=59.5613
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Diff_params/Hbeta_diff_fit.csv", index_col=0)
initial_guesses = np.concatenate([
    df['Component 1'].values,  # [I_e, r_e, n, x_0] per Component 1
    df['Component 2'].values,  # [I_e, r_e, n, x_0] per Component 2
    df['Component 3'].values   # [I_e, r_e, n, x_0] per Component 3
])
print(df)
bounds = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 5),  # n: da 0.1 a 10
    (38, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 5),
    (0.1, 5),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 1),
    (90, 110),
    (0.1, 5),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2),
]
# Out:
#      Component 1  Component 2  Component 3
# I_e       4.4717       3.3913       0.0440
# r_e       6.2760       1.6236      99.9989
# n         1.7266       0.2416       3.0970
# x_0      38.1366      48.9157      80.3384

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=initial_guesses, sigma = real_errors_HB, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2821, r_e=34.8298, n=4.0605, x_0=38.0000
# Sérsic 2: I_e=2.4576, r_e=1.6358, n=0.4000, x_0=48.8252
# Sérsic 3: I_e=0.0246, r_e=90.0002, n=3.7886, x_0=80.7667
# [4.06022989e-01 3.08191669e+01 1.96379598e+00 4.50590046e-02
#  2.24036256e+00 5.10954873e-01 7.37746160e-01 3.06937553e-01
#  7.18688543e-02 2.09828828e+02 2.15544790e+00 2.05805558e-01]
# 15.480879707927729

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 13219.918954222683
# differential_evolution step 2: f(x)= 13219.918954222683
# differential_evolution step 3: f(x)= 13219.918954222683
# differential_evolution step 4: f(x)= 4316.295465382007
# differential_evolution step 5: f(x)= 2469.9883280369036
# differential_evolution step 6: f(x)= 2461.035562146304
# differential_evolution step 7: f(x)= 2461.035562146304
# differential_evolution step 8: f(x)= 713.7999074261396
# differential_evolution step 9: f(x)= 202.86197734263718
# differential_evolution step 10: f(x)= 202.86197734263718
# differential_evolution step 11: f(x)= 202.86197734263718
# differential_evolution step 12: f(x)= 202.86197734263718
# differential_evolution step 13: f(x)= 202.86197734263718
# differential_evolution step 14: f(x)= 202.86197734263718
# differential_evolution step 15: f(x)= 202.86197734263718
# differential_evolution step 16: f(x)= 202.86197734263718
# differential_evolution step 17: f(x)= 202.86197734263718
# differential_evolution step 18: f(x)= 202.86197734263718
# differential_evolution step 19: f(x)= 202.86197734263718
# differential_evolution step 20: f(x)= 106.52622315671196
# differential_evolution step 21: f(x)= 89.38594334475178
# differential_evolution step 22: f(x)= 89.38594334475178
# differential_evolution step 23: f(x)= 89.38594334475178
# differential_evolution step 24: f(x)= 89.38594334475178
# differential_evolution step 25: f(x)= 89.38594334475178
# differential_evolution step 26: f(x)= 89.38594334475178
# differential_evolution step 27: f(x)= 43.33154616235484
# differential_evolution step 28: f(x)= 43.33154616235484
# differential_evolution step 29: f(x)= 43.33154616235484
# differential_evolution step 30: f(x)= 31.214590710396806
# differential_evolution step 31: f(x)= 31.214590710396806
# differential_evolution step 32: f(x)= 31.214590710396806
# differential_evolution step 33: f(x)= 30.59021364512356
# differential_evolution step 34: f(x)= 30.59021364512356
# differential_evolution step 35: f(x)= 30.59021364512356
# differential_evolution step 36: f(x)= 30.59021364512356
# differential_evolution step 37: f(x)= 30.59021364512356
# differential_evolution step 38: f(x)= 25.76998319451145
# differential_evolution step 39: f(x)= 17.76433347612048
# differential_evolution step 40: f(x)= 17.76433347612048
# differential_evolution step 41: f(x)= 17.76433347612048
# differential_evolution step 42: f(x)= 17.76433347612048
# differential_evolution step 43: f(x)= 17.76433347612048
# differential_evolution step 44: f(x)= 14.553464230550915
# differential_evolution step 45: f(x)= 14.553464230550915
# differential_evolution step 46: f(x)= 14.553464230550915
# differential_evolution step 47: f(x)= 14.553464230550915
# differential_evolution step 48: f(x)= 14.553464230550915
# differential_evolution step 49: f(x)= 12.860473876964218
# differential_evolution step 50: f(x)= 12.860473876964218
# differential_evolution step 51: f(x)= 9.621016040756455
# differential_evolution step 52: f(x)= 9.621016040756455
# differential_evolution step 53: f(x)= 9.621016040756455
# differential_evolution step 54: f(x)= 9.621016040756455
# differential_evolution step 55: f(x)= 9.621016040756455
# differential_evolution step 56: f(x)= 9.621016040756455
# differential_evolution step 57: f(x)= 9.621016040756455
# differential_evolution step 58: f(x)= 9.621016040756455
# differential_evolution step 59: f(x)= 9.621016040756455
# differential_evolution step 60: f(x)= 9.621016040756455
# differential_evolution step 61: f(x)= 9.621016040756455
# differential_evolution step 62: f(x)= 9.621016040756455
# differential_evolution step 63: f(x)= 9.621016040756455
# differential_evolution step 64: f(x)= 9.621016040756455
# differential_evolution step 65: f(x)= 9.621016040756455
# differential_evolution step 66: f(x)= 9.621016040756455
# differential_evolution step 67: f(x)= 9.621016040756455
# differential_evolution step 68: f(x)= 9.621016040756455
# differential_evolution step 69: f(x)= 9.621016040756455
# differential_evolution step 70: f(x)= 9.621016040756455
# differential_evolution step 71: f(x)= 6.433976364047865
# differential_evolution step 72: f(x)= 5.902897296102703
# differential_evolution step 73: f(x)= 5.902897296102703
# differential_evolution step 74: f(x)= 5.902897296102703
# differential_evolution step 75: f(x)= 5.902897296102703
# differential_evolution step 76: f(x)= 5.902897296102703
# differential_evolution step 77: f(x)= 5.902897296102703
# differential_evolution step 78: f(x)= 5.902897296102703
# differential_evolution step 79: f(x)= 5.902897296102703
# differential_evolution step 80: f(x)= 5.902897296102703
# differential_evolution step 81: f(x)= 5.902897296102703
# differential_evolution step 82: f(x)= 5.902897296102703
# differential_evolution step 83: f(x)= 5.668794952961545
# differential_evolution step 84: f(x)= 5.668794952961545
# differential_evolution step 85: f(x)= 5.668794952961545
# differential_evolution step 86: f(x)= 5.668794952961545
# differential_evolution step 87: f(x)= 5.668794952961545
# differential_evolution step 88: f(x)= 5.668794952961545
# differential_evolution step 89: f(x)= 5.668794952961545
# differential_evolution step 90: f(x)= 5.668794952961545
# differential_evolution step 91: f(x)= 5.668794952961545
# differential_evolution step 92: f(x)= 5.668794952961545
# differential_evolution step 93: f(x)= 5.668794952961545
# differential_evolution step 94: f(x)= 5.668794952961545
# differential_evolution step 95: f(x)= 5.668794952961545
# differential_evolution step 96: f(x)= 5.532505276474192
# differential_evolution step 97: f(x)= 5.532505276474192
# differential_evolution step 98: f(x)= 5.532505276474192
# differential_evolution step 99: f(x)= 5.532505276474192
# differential_evolution step 100: f(x)= 5.466767672433768
# differential_evolution step 101: f(x)= 5.466767672433768
# differential_evolution step 102: f(x)= 5.466767672433768
# differential_evolution step 103: f(x)= 5.466767672433768
# differential_evolution step 104: f(x)= 5.466767672433768
# differential_evolution step 105: f(x)= 5.389984447250112
# differential_evolution step 106: f(x)= 5.389984447250112
# differential_evolution step 107: f(x)= 5.389984447250112
# differential_evolution step 108: f(x)= 5.3080713639058485
# differential_evolution step 109: f(x)= 5.3080713639058485
# differential_evolution step 110: f(x)= 5.3080713639058485
# differential_evolution step 111: f(x)= 5.3080713639058485
# differential_evolution step 112: f(x)= 5.3080713639058485
# differential_evolution step 113: f(x)= 5.3080713639058485
# differential_evolution step 114: f(x)= 5.3080713639058485
# differential_evolution step 115: f(x)= 5.3080713639058485
# differential_evolution step 116: f(x)= 5.3080713639058485
# differential_evolution step 117: f(x)= 5.3080713639058485
# differential_evolution step 118: f(x)= 5.138366656089848
# differential_evolution step 119: f(x)= 4.487974067421396
# differential_evolution step 120: f(x)= 3.5272884831701212
# differential_evolution step 121: f(x)= 3.5272884831701212
# differential_evolution step 122: f(x)= 3.5272884831701212
# differential_evolution step 123: f(x)= 3.5272884831701212
# differential_evolution step 124: f(x)= 3.5272884831701212
# differential_evolution step 125: f(x)= 3.5272884831701212
# differential_evolution step 126: f(x)= 3.5272884831701212
# differential_evolution step 127: f(x)= 3.5272884831701212
# differential_evolution step 128: f(x)= 3.0233902989946877
# differential_evolution step 129: f(x)= 3.0233902989946877
# differential_evolution step 130: f(x)= 3.0233902989946877
# differential_evolution step 131: f(x)= 3.0233902989946877
# differential_evolution step 132: f(x)= 3.0233902989946877
# differential_evolution step 133: f(x)= 3.0233902989946877
# differential_evolution step 134: f(x)= 2.9942629575874364
# differential_evolution step 135: f(x)= 2.9942629575874364
# differential_evolution step 136: f(x)= 2.9942629575874364
# differential_evolution step 137: f(x)= 2.9942629575874364
# differential_evolution step 138: f(x)= 2.9942629575874364
# differential_evolution step 139: f(x)= 2.929534837032298
# differential_evolution step 140: f(x)= 2.929534837032298
# differential_evolution step 141: f(x)= 2.929534837032298
# differential_evolution step 142: f(x)= 2.929534837032298
# differential_evolution step 143: f(x)= 2.929534837032298
# differential_evolution step 144: f(x)= 2.929534837032298
# differential_evolution step 145: f(x)= 2.929534837032298
# differential_evolution step 146: f(x)= 2.929534837032298
# differential_evolution step 147: f(x)= 2.929534837032298
# differential_evolution step 148: f(x)= 2.929534837032298
# differential_evolution step 149: f(x)= 2.929534837032298
# differential_evolution step 150: f(x)= 2.88520663915704
# differential_evolution step 151: f(x)= 2.88520663915704
# differential_evolution step 152: f(x)= 2.88520663915704
# differential_evolution step 153: f(x)= 2.88520663915704
# differential_evolution step 154: f(x)= 2.88520663915704
# differential_evolution step 155: f(x)= 2.88520663915704
# differential_evolution step 156: f(x)= 2.88520663915704
# differential_evolution step 157: f(x)= 2.88520663915704
# differential_evolution step 158: f(x)= 2.88520663915704
# differential_evolution step 159: f(x)= 2.88520663915704
# differential_evolution step 160: f(x)= 2.88520663915704
# differential_evolution step 161: f(x)= 2.868345965018944
# differential_evolution step 162: f(x)= 2.868345965018944
# differential_evolution step 163: f(x)= 2.868345965018944
# differential_evolution step 164: f(x)= 2.868345965018944
# differential_evolution step 165: f(x)= 2.868345965018944
# differential_evolution step 166: f(x)= 2.868345965018944
# differential_evolution step 167: f(x)= 2.868345965018944
# differential_evolution step 168: f(x)= 2.8338681547902485
# differential_evolution step 169: f(x)= 2.8338681547902485
# differential_evolution step 170: f(x)= 2.8338681547902485
# differential_evolution step 171: f(x)= 2.5434044270130034
# differential_evolution step 172: f(x)= 2.5434044270130034
# differential_evolution step 173: f(x)= 2.5434044270130034
# differential_evolution step 174: f(x)= 2.5434044270130034
# differential_evolution step 175: f(x)= 2.5434044270130034
# differential_evolution step 176: f(x)= 2.5434044270130034
# differential_evolution step 177: f(x)= 2.5434044270130034
# differential_evolution step 178: f(x)= 2.5434044270130034
# differential_evolution step 179: f(x)= 2.5434044270130034
# differential_evolution step 180: f(x)= 2.3003345767302243
# differential_evolution step 181: f(x)= 2.3003345767302243
# differential_evolution step 182: f(x)= 2.3003345767302243
# differential_evolution step 183: f(x)= 2.3003345767302243
# differential_evolution step 184: f(x)= 2.3003345767302243
# differential_evolution step 185: f(x)= 2.3003345767302243
# differential_evolution step 186: f(x)= 2.3003345767302243
# differential_evolution step 187: f(x)= 2.3003345767302243
# differential_evolution step 188: f(x)= 2.3003345767302243
# differential_evolution step 189: f(x)= 2.3003345767302243
# differential_evolution step 190: f(x)= 2.3003345767302243
# differential_evolution step 191: f(x)= 2.3003345767302243
# differential_evolution step 192: f(x)= 2.3003345767302243
# differential_evolution step 193: f(x)= 2.3003345767302243
# differential_evolution step 194: f(x)= 2.3003345767302243
# differential_evolution step 195: f(x)= 2.3003345767302243
# differential_evolution step 196: f(x)= 2.3003345767302243
# differential_evolution step 197: f(x)= 2.3003345767302243
# differential_evolution step 198: f(x)= 2.3003345767302243
# differential_evolution step 199: f(x)= 2.3003345767302243
# differential_evolution step 200: f(x)= 2.3003345767302243
# differential_evolution step 201: f(x)= 2.3003345767302243
# differential_evolution step 202: f(x)= 2.3003345767302243
# differential_evolution step 203: f(x)= 2.3003345767302243
# differential_evolution step 204: f(x)= 2.3003345767302243
# differential_evolution step 205: f(x)= 2.3003345767302243
# differential_evolution step 206: f(x)= 2.3003345767302243
# differential_evolution step 207: f(x)= 2.3003345767302243
# differential_evolution step 208: f(x)= 2.2009907705065896
# differential_evolution step 209: f(x)= 2.2009907705065896
# differential_evolution step 210: f(x)= 2.2009907705065896
# differential_evolution step 211: f(x)= 2.2009907705065896
# differential_evolution step 212: f(x)= 2.2009907705065896
# differential_evolution step 213: f(x)= 2.2009907705065896
# differential_evolution step 214: f(x)= 2.2009907705065896
# differential_evolution step 215: f(x)= 2.2009907705065896
# differential_evolution step 216: f(x)= 2.2009907705065896
# differential_evolution step 217: f(x)= 2.2009907705065896
# differential_evolution step 218: f(x)= 2.0796317708946384
# differential_evolution step 219: f(x)= 2.059958231535526
# differential_evolution step 220: f(x)= 2.059958231535526
# differential_evolution step 221: f(x)= 2.059958231535526
# differential_evolution step 222: f(x)= 2.059958231535526
# differential_evolution step 223: f(x)= 2.059628105193273
# differential_evolution step 224: f(x)= 2.059628105193273
# differential_evolution step 225: f(x)= 2.059628105193273
# differential_evolution step 226: f(x)= 2.059628105193273
# differential_evolution step 227: f(x)= 2.059628105193273
# differential_evolution step 228: f(x)= 2.059628105193273
# differential_evolution step 229: f(x)= 2.058651495221616
# differential_evolution step 230: f(x)= 2.058651495221616
# differential_evolution step 231: f(x)= 2.058651495221616
# differential_evolution step 232: f(x)= 2.058651495221616
# differential_evolution step 233: f(x)= 2.058651495221616
# differential_evolution step 234: f(x)= 2.058651495221616
# differential_evolution step 235: f(x)= 2.058651495221616
# differential_evolution step 236: f(x)= 2.058651495221616
# differential_evolution step 237: f(x)= 2.058651495221616
# differential_evolution step 238: f(x)= 2.058651495221616
# differential_evolution step 239: f(x)= 2.058651495221616
# differential_evolution step 240: f(x)= 2.058651495221616
# differential_evolution step 241: f(x)= 2.058651495221616
# differential_evolution step 242: f(x)= 2.058651495221616
# differential_evolution step 243: f(x)= 2.058651495221616
# differential_evolution step 244: f(x)= 2.055266922147908
# differential_evolution step 245: f(x)= 2.055266922147908
# differential_evolution step 246: f(x)= 2.055266922147908
# differential_evolution step 247: f(x)= 2.055266922147908
# differential_evolution step 248: f(x)= 2.055266922147908
# differential_evolution step 249: f(x)= 2.055266922147908
# differential_evolution step 250: f(x)= 2.055266922147908
# differential_evolution step 251: f(x)= 2.055266922147908
# differential_evolution step 252: f(x)= 2.055266922147908
# differential_evolution step 253: f(x)= 2.055266922147908
# differential_evolution step 254: f(x)= 2.055266922147908
# differential_evolution step 255: f(x)= 2.055266922147908
# differential_evolution step 256: f(x)= 2.055266922147908
# differential_evolution step 257: f(x)= 2.055266922147908
# differential_evolution step 258: f(x)= 2.017353202839812
# differential_evolution step 259: f(x)= 2.017353202839812
# differential_evolution step 260: f(x)= 2.017353202839812
# differential_evolution step 261: f(x)= 2.017353202839812
# differential_evolution step 262: f(x)= 2.017353202839812
# differential_evolution step 263: f(x)= 2.017353202839812
# differential_evolution step 264: f(x)= 2.017353202839812
# differential_evolution step 265: f(x)= 2.017353202839812
# differential_evolution step 266: f(x)= 2.017353202839812
# differential_evolution step 267: f(x)= 2.017353202839812
# differential_evolution step 268: f(x)= 2.017353202839812
# differential_evolution step 269: f(x)= 2.0058499037907005
# differential_evolution step 270: f(x)= 2.0058499037907005
# differential_evolution step 271: f(x)= 2.0058499037907005
# differential_evolution step 272: f(x)= 2.0058499037907005
# differential_evolution step 273: f(x)= 2.0058499037907005
# differential_evolution step 274: f(x)= 2.0058499037907005
# differential_evolution step 275: f(x)= 2.0058499037907005
# differential_evolution step 276: f(x)= 2.0058499037907005
# differential_evolution step 277: f(x)= 2.0001953392773433
# differential_evolution step 278: f(x)= 2.0001953392773433
# differential_evolution step 279: f(x)= 2.0001953392773433
# differential_evolution step 280: f(x)= 1.9980288562054962
# differential_evolution step 281: f(x)= 1.995953774868222
# differential_evolution step 282: f(x)= 1.995953774868222
# differential_evolution step 283: f(x)= 1.995953774868222
# differential_evolution step 284: f(x)= 1.995953774868222
# differential_evolution step 285: f(x)= 1.995953774868222
# differential_evolution step 286: f(x)= 1.995953774868222
# differential_evolution step 287: f(x)= 1.995953774868222
# differential_evolution step 288: f(x)= 1.995953774868222
# differential_evolution step 289: f(x)= 1.995953774868222
# differential_evolution step 290: f(x)= 1.995953774868222
# differential_evolution step 291: f(x)= 1.9927338991026564
# differential_evolution step 292: f(x)= 1.9927338991026564
# differential_evolution step 293: f(x)= 1.9927338991026564
# differential_evolution step 294: f(x)= 1.9927338991026564
# differential_evolution step 295: f(x)= 1.9869283092287315
# differential_evolution step 296: f(x)= 1.9869283092287315
# differential_evolution step 297: f(x)= 1.9869283092287315
# differential_evolution step 298: f(x)= 1.9582118125941559
# differential_evolution step 299: f(x)= 1.9582118125941559
# differential_evolution step 300: f(x)= 1.9582118125941559
# differential_evolution step 301: f(x)= 1.9582118125941559
# differential_evolution step 302: f(x)= 1.9582118125941559
# differential_evolution step 303: f(x)= 1.9582118125941559
# differential_evolution step 304: f(x)= 1.9582118125941559
# differential_evolution step 305: f(x)= 1.9582118125941559
# differential_evolution step 306: f(x)= 1.9582118125941559
# differential_evolution step 307: f(x)= 1.9582118125941559
# differential_evolution step 308: f(x)= 1.9582118125941559
# differential_evolution step 309: f(x)= 1.9582118125941559
# differential_evolution step 310: f(x)= 1.9582118125941559
# differential_evolution step 311: f(x)= 1.9529689302548603
# differential_evolution step 312: f(x)= 1.9529689302548603
# differential_evolution step 313: f(x)= 1.9529689302548603
# differential_evolution step 314: f(x)= 1.9529689302548603
# differential_evolution step 315: f(x)= 1.9529689302548603
# differential_evolution step 316: f(x)= 1.9529689302548603
# differential_evolution step 317: f(x)= 1.9529689302548603
# differential_evolution step 318: f(x)= 1.9529689302548603
# differential_evolution step 319: f(x)= 1.9529689302548603
# differential_evolution step 320: f(x)= 1.9529689302548603
# differential_evolution step 321: f(x)= 1.9529689302548603
# differential_evolution step 322: f(x)= 1.9529689302548603
# differential_evolution step 323: f(x)= 1.9529689302548603
# differential_evolution step 324: f(x)= 1.9366077894158056
# differential_evolution step 325: f(x)= 1.9366077894158056
# differential_evolution step 326: f(x)= 1.9366077894158056
# differential_evolution step 327: f(x)= 1.9366077894158056
# differential_evolution step 328: f(x)= 1.9366077894158056
# differential_evolution step 329: f(x)= 1.9366077894158056
# differential_evolution step 330: f(x)= 1.9366077894158056
# differential_evolution step 331: f(x)= 1.9366077894158056
# differential_evolution step 332: f(x)= 1.9366077894158056
# differential_evolution step 333: f(x)= 1.9366077894158056
# differential_evolution step 334: f(x)= 1.9366077894158056
# differential_evolution step 335: f(x)= 1.9366077894158056
# differential_evolution step 336: f(x)= 1.9366077894158056
# differential_evolution step 337: f(x)= 1.9366077894158056
# differential_evolution step 338: f(x)= 1.9366077894158056
# differential_evolution step 339: f(x)= 1.9340563803014503
# differential_evolution step 340: f(x)= 1.9328506380492005
# differential_evolution step 341: f(x)= 1.9328506380492005
# differential_evolution step 342: f(x)= 1.9328506380492005
# differential_evolution step 343: f(x)= 1.9328506380492005
# differential_evolution step 344: f(x)= 1.9328506380492005
# differential_evolution step 345: f(x)= 1.9301867606914738
# differential_evolution step 346: f(x)= 1.9301867606914738
# differential_evolution step 347: f(x)= 1.9301867606914738
# differential_evolution step 348: f(x)= 1.9301867606914738
# differential_evolution step 349: f(x)= 1.9301867606914738
# differential_evolution step 350: f(x)= 1.9301867606914738
# differential_evolution step 351: f(x)= 1.9301867606914738
# differential_evolution step 352: f(x)= 1.9301867606914738
# differential_evolution step 353: f(x)= 1.9301867606914738
# differential_evolution step 354: f(x)= 1.9301867606914738
# differential_evolution step 355: f(x)= 1.9301867606914738
# differential_evolution step 356: f(x)= 1.9301867606914738
# differential_evolution step 357: f(x)= 1.9301867606914738
# differential_evolution step 358: f(x)= 1.9301867606914738
# differential_evolution step 359: f(x)= 1.9301867606914738
# differential_evolution step 360: f(x)= 1.9301867606914738
# differential_evolution step 361: f(x)= 1.9301867606914738
# differential_evolution step 362: f(x)= 1.9301867606914738
# differential_evolution step 363: f(x)= 1.9301867606914738
# differential_evolution step 364: f(x)= 1.9301867606914738
# differential_evolution step 365: f(x)= 1.9301867606914738
# differential_evolution step 366: f(x)= 1.9300693138143215
# differential_evolution step 367: f(x)= 1.9300693138143215
# differential_evolution step 368: f(x)= 1.9300693138143215
# differential_evolution step 369: f(x)= 1.9300693138143215
# differential_evolution step 370: f(x)= 1.9300693138143215
# differential_evolution step 371: f(x)= 1.9291107751350949
# differential_evolution step 372: f(x)= 1.9291107751350949
# differential_evolution step 373: f(x)= 1.9291107751350949
# differential_evolution step 374: f(x)= 1.928053829389876
# differential_evolution step 375: f(x)= 1.928053829389876
# differential_evolution step 376: f(x)= 1.928053829389876
# differential_evolution step 377: f(x)= 1.926893345895627
# differential_evolution step 378: f(x)= 1.926893345895627
# differential_evolution step 379: f(x)= 1.926893345895627
# differential_evolution step 380: f(x)= 1.926893345895627
# differential_evolution step 381: f(x)= 1.9244844502988925
# differential_evolution step 382: f(x)= 1.9239288375631918
# differential_evolution step 383: f(x)= 1.9239288375631918
# differential_evolution step 384: f(x)= 1.9239288375631918
# differential_evolution step 385: f(x)= 1.9239288375631918
# differential_evolution step 386: f(x)= 1.9239288375631918
# differential_evolution step 387: f(x)= 1.9239288375631918
# differential_evolution step 388: f(x)= 1.9239288375631918
# differential_evolution step 389: f(x)= 1.9239288375631918
# differential_evolution step 390: f(x)= 1.9239288375631918
# differential_evolution step 391: f(x)= 1.9239288375631918
# differential_evolution step 392: f(x)= 1.9239288375631918
# differential_evolution step 393: f(x)= 1.9239288375631918
# differential_evolution step 394: f(x)= 1.9239288375631918
# differential_evolution step 395: f(x)= 1.9239288375631918
# differential_evolution step 396: f(x)= 1.9239288375631918
# differential_evolution step 397: f(x)= 1.9239288375631918
# differential_evolution step 398: f(x)= 1.9239288375631918
# differential_evolution step 399: f(x)= 1.9239288375631918
# differential_evolution step 400: f(x)= 1.920231255209165
# differential_evolution step 401: f(x)= 1.920231255209165
# differential_evolution step 402: f(x)= 1.920231255209165
# differential_evolution step 403: f(x)= 1.920231255209165
# differential_evolution step 404: f(x)= 1.920231255209165
# differential_evolution step 405: f(x)= 1.920231255209165
# differential_evolution step 406: f(x)= 1.920231255209165
# differential_evolution step 407: f(x)= 1.920231255209165
# differential_evolution step 408: f(x)= 1.920231255209165
# differential_evolution step 409: f(x)= 1.920231255209165
# differential_evolution step 410: f(x)= 1.920231255209165
# differential_evolution step 411: f(x)= 1.920231255209165
# differential_evolution step 412: f(x)= 1.920231255209165
# differential_evolution step 413: f(x)= 1.9180232596239177
# differential_evolution step 414: f(x)= 1.9180232596239177
# differential_evolution step 415: f(x)= 1.9180232596239177
# differential_evolution step 416: f(x)= 1.9180232596239177
# differential_evolution step 417: f(x)= 1.9149130112309949
# differential_evolution step 418: f(x)= 1.9149130112309949
# differential_evolution step 419: f(x)= 1.9149130112309949
# differential_evolution step 420: f(x)= 1.9149130112309949
# differential_evolution step 421: f(x)= 1.9149130112309949
# differential_evolution step 422: f(x)= 1.9149130112309949
# differential_evolution step 423: f(x)= 1.9149130112309949
# differential_evolution step 424: f(x)= 1.9149130112309949
# differential_evolution step 425: f(x)= 1.9149130112309949
# differential_evolution step 426: f(x)= 1.9147086694433895
# differential_evolution step 427: f(x)= 1.9147086694433895
# differential_evolution step 428: f(x)= 1.9147086694433895
# differential_evolution step 429: f(x)= 1.9147086694433895
# differential_evolution step 430: f(x)= 1.9147086694433895
# differential_evolution step 431: f(x)= 1.9147086694433895
# differential_evolution step 432: f(x)= 1.9123616469771065
# differential_evolution step 433: f(x)= 1.9123616469771065
# differential_evolution step 434: f(x)= 1.9123616469771065
# differential_evolution step 435: f(x)= 1.9123616469771065
# differential_evolution step 436: f(x)= 1.9123616469771065
# differential_evolution step 437: f(x)= 1.9123616469771065
# differential_evolution step 438: f(x)= 1.9123616469771065
# differential_evolution step 439: f(x)= 1.9123616469771065
# differential_evolution step 440: f(x)= 1.9123616469771065
# differential_evolution step 441: f(x)= 1.9123616469771065
# differential_evolution step 442: f(x)= 1.9123616469771065
# differential_evolution step 443: f(x)= 1.9123616469771065
# differential_evolution step 444: f(x)= 1.9109873973214773
# differential_evolution step 445: f(x)= 1.9109873973214773
# differential_evolution step 446: f(x)= 1.9109873973214773
# differential_evolution step 447: f(x)= 1.9109873973214773
# differential_evolution step 448: f(x)= 1.9109873973214773
# differential_evolution step 449: f(x)= 1.9109873973214773
# differential_evolution step 450: f(x)= 1.9109873973214773
# differential_evolution step 451: f(x)= 1.9109873973214773
# differential_evolution step 452: f(x)= 1.9109873973214773
# differential_evolution step 453: f(x)= 1.9109873973214773
# differential_evolution step 454: f(x)= 1.9109873973214773
# differential_evolution step 455: f(x)= 1.9109873973214773
# differential_evolution step 456: f(x)= 1.9109873973214773
# differential_evolution step 457: f(x)= 1.907926296438034
# differential_evolution step 458: f(x)= 1.907926296438034
# differential_evolution step 459: f(x)= 1.907926296438034
# differential_evolution step 460: f(x)= 1.907926296438034
# differential_evolution step 461: f(x)= 1.907926296438034
# differential_evolution step 462: f(x)= 1.907926296438034
# differential_evolution step 463: f(x)= 1.907926296438034
# differential_evolution step 464: f(x)= 1.907926296438034
# differential_evolution step 465: f(x)= 1.907926296438034
# differential_evolution step 466: f(x)= 1.907926296438034
# differential_evolution step 467: f(x)= 1.907926296438034
# differential_evolution step 468: f(x)= 1.907926296438034
# differential_evolution step 469: f(x)= 1.907926296438034
# differential_evolution step 470: f(x)= 1.907926296438034
# differential_evolution step 471: f(x)= 1.907926296438034
# differential_evolution step 472: f(x)= 1.907926296438034
# differential_evolution step 473: f(x)= 1.907926296438034
# differential_evolution step 474: f(x)= 1.9076047981884396
# differential_evolution step 475: f(x)= 1.9072252726264545
# differential_evolution step 476: f(x)= 1.9072252726264545
# differential_evolution step 477: f(x)= 1.9068946843924677
# differential_evolution step 478: f(x)= 1.9068946843924677
# differential_evolution step 479: f(x)= 1.9068946843924677
# differential_evolution step 480: f(x)= 1.9057134822046533
# differential_evolution step 481: f(x)= 1.9057134822046533
# differential_evolution step 482: f(x)= 1.9057134822046533
# differential_evolution step 483: f(x)= 1.9057134822046533
# differential_evolution step 484: f(x)= 1.9057134822046533
# differential_evolution step 485: f(x)= 1.9057134822046533
# differential_evolution step 486: f(x)= 1.9057134822046533
# differential_evolution step 487: f(x)= 1.9057134822046533
# differential_evolution step 488: f(x)= 1.9057134822046533
# differential_evolution step 489: f(x)= 1.9057134822046533
# differential_evolution step 490: f(x)= 1.9057134822046533
# differential_evolution step 491: f(x)= 1.9057134822046533
# differential_evolution step 492: f(x)= 1.9057134822046533
# differential_evolution step 493: f(x)= 1.9057134822046533
# differential_evolution step 494: f(x)= 1.9057134822046533
# differential_evolution step 495: f(x)= 1.9057134822046533
# differential_evolution step 496: f(x)= 1.9057134822046533
# differential_evolution step 497: f(x)= 1.9057134822046533
# differential_evolution step 498: f(x)= 1.9057134822046533
# differential_evolution step 499: f(x)= 1.9057134822046533
# differential_evolution step 500: f(x)= 1.9057134822046533
# differential_evolution step 501: f(x)= 1.9057134822046533
# differential_evolution step 502: f(x)= 1.9057134822046533
# differential_evolution step 503: f(x)= 1.9057134822046533
# differential_evolution step 504: f(x)= 1.9057134822046533
# differential_evolution step 505: f(x)= 1.9057134822046533
# differential_evolution step 506: f(x)= 1.9048275748787828
# differential_evolution step 507: f(x)= 1.9048275748787828
# differential_evolution step 508: f(x)= 1.903206707261611
# differential_evolution step 509: f(x)= 1.903206707261611
# differential_evolution step 510: f(x)= 1.903206707261611
# differential_evolution step 511: f(x)= 1.903206707261611
# differential_evolution step 512: f(x)= 1.903206707261611
# differential_evolution step 513: f(x)= 1.9021620620984514
# differential_evolution step 514: f(x)= 1.9021620620984514
# differential_evolution step 515: f(x)= 1.9021620620984514
# differential_evolution step 516: f(x)= 1.9021620620984514
# differential_evolution step 517: f(x)= 1.9017828595013522
# differential_evolution step 518: f(x)= 1.9015443746219134
# differential_evolution step 519: f(x)= 1.9012537832210967
# differential_evolution step 520: f(x)= 1.9012537832210967
# differential_evolution step 521: f(x)= 1.8941219768470865
# differential_evolution step 522: f(x)= 1.8941219768470865
# differential_evolution step 523: f(x)= 1.8941219768470865
# differential_evolution step 524: f(x)= 1.8941042738954876
# differential_evolution step 525: f(x)= 1.8941042738954876
# differential_evolution step 526: f(x)= 1.8941042738954876
# differential_evolution step 527: f(x)= 1.8941042738954876
# differential_evolution step 528: f(x)= 1.892731082331931
# differential_evolution step 529: f(x)= 1.884338532838317
# differential_evolution step 530: f(x)= 1.884338532838317
# differential_evolution step 531: f(x)= 1.8829789031096045
# differential_evolution step 532: f(x)= 1.8829789031096045
# differential_evolution step 533: f(x)= 1.8829789031096045
# differential_evolution step 534: f(x)= 1.8829789031096045
# differential_evolution step 535: f(x)= 1.8829789031096045
# differential_evolution step 536: f(x)= 1.8829789031096045
# differential_evolution step 537: f(x)= 1.8829789031096045
# differential_evolution step 538: f(x)= 1.8824716243709287
# differential_evolution step 539: f(x)= 1.876956763473915
# differential_evolution step 540: f(x)= 1.876956763473915
# differential_evolution step 541: f(x)= 1.876956763473915
# differential_evolution step 542: f(x)= 1.876956763473915
# differential_evolution step 543: f(x)= 1.8763265167039742
# differential_evolution step 544: f(x)= 1.8763265167039742
# differential_evolution step 545: f(x)= 1.8763265167039742
# differential_evolution step 546: f(x)= 1.8707067770284531
# differential_evolution step 547: f(x)= 1.8707067770284531
# differential_evolution step 548: f(x)= 1.8707067770284531
# differential_evolution step 549: f(x)= 1.8707067770284531
# differential_evolution step 550: f(x)= 1.8707067770284531
# differential_evolution step 551: f(x)= 1.8707067770284531
# differential_evolution step 552: f(x)= 1.8684943415404682
# differential_evolution step 553: f(x)= 1.8684943415404682
# differential_evolution step 554: f(x)= 1.8684943415404682
# differential_evolution step 555: f(x)= 1.8639387733284287
# differential_evolution step 556: f(x)= 1.84625612674617
# differential_evolution step 557: f(x)= 1.84625612674617
# differential_evolution step 558: f(x)= 1.84625612674617
# differential_evolution step 559: f(x)= 1.84625612674617
# differential_evolution step 560: f(x)= 1.84625612674617
# differential_evolution step 561: f(x)= 1.84625612674617
# differential_evolution step 562: f(x)= 1.84625612674617
# differential_evolution step 563: f(x)= 1.84625612674617
# differential_evolution step 564: f(x)= 1.84625612674617
# differential_evolution step 565: f(x)= 1.8423080220276373
# differential_evolution step 566: f(x)= 1.8283568435982942
# differential_evolution step 567: f(x)= 1.8283568435982942
# differential_evolution step 568: f(x)= 1.827409163492095
# differential_evolution step 569: f(x)= 1.8256133381263893
# differential_evolution step 570: f(x)= 1.822948372453513
# differential_evolution step 571: f(x)= 1.822948372453513
# differential_evolution step 572: f(x)= 1.822948372453513
# differential_evolution step 573: f(x)= 1.822948372453513
# differential_evolution step 574: f(x)= 1.8138887159504282
# differential_evolution step 575: f(x)= 1.8138887159504282
# differential_evolution step 576: f(x)= 1.8138887159504282
# differential_evolution step 577: f(x)= 1.8066767365303373
# differential_evolution step 578: f(x)= 1.8066767365303373
# differential_evolution step 579: f(x)= 1.8066767365303373
# differential_evolution step 580: f(x)= 1.7991618053285705
# differential_evolution step 581: f(x)= 1.7991618053285705
# differential_evolution step 582: f(x)= 1.7991618053285705
# differential_evolution step 583: f(x)= 1.7991618053285705
# differential_evolution step 584: f(x)= 1.7991618053285705
# differential_evolution step 585: f(x)= 1.7991618053285705
# differential_evolution step 586: f(x)= 1.7991618053285705
# differential_evolution step 587: f(x)= 1.7991618053285705
# differential_evolution step 588: f(x)= 1.7991618053285705
# differential_evolution step 589: f(x)= 1.7991618053285705
# differential_evolution step 590: f(x)= 1.7991618053285705
# differential_evolution step 591: f(x)= 1.7991618053285705
# differential_evolution step 592: f(x)= 1.7991618053285705
# differential_evolution step 593: f(x)= 1.7991618053285705
# differential_evolution step 594: f(x)= 1.7991618053285705
# differential_evolution step 595: f(x)= 1.7991618053285705
# differential_evolution step 596: f(x)= 1.7962164358260528
# differential_evolution step 597: f(x)= 1.7962164358260528
# differential_evolution step 598: f(x)= 1.7843297937379285
# differential_evolution step 599: f(x)= 1.7843297937379285
# differential_evolution step 600: f(x)= 1.778248725885087
# differential_evolution step 601: f(x)= 1.7769754258273907
# differential_evolution step 602: f(x)= 1.7709799755203726
# differential_evolution step 603: f(x)= 1.7691573394006122
# differential_evolution step 604: f(x)= 1.7619538394724599
# differential_evolution step 605: f(x)= 1.7581298291605407
# differential_evolution step 606: f(x)= 1.7581298291605407
# differential_evolution step 607: f(x)= 1.7508987992485874
# differential_evolution step 608: f(x)= 1.7416929540775221
# differential_evolution step 609: f(x)= 1.739065312386115
# differential_evolution step 610: f(x)= 1.739065312386115
# differential_evolution step 611: f(x)= 1.739065312386115
# differential_evolution step 612: f(x)= 1.7120202692965119
# differential_evolution step 613: f(x)= 1.7120202692965119
# differential_evolution step 614: f(x)= 1.7120202692965119
# differential_evolution step 615: f(x)= 1.7111112312789427
# differential_evolution step 616: f(x)= 1.651820961208699
# differential_evolution step 617: f(x)= 1.639404157477051
# differential_evolution step 618: f(x)= 1.639404157477051
# differential_evolution step 619: f(x)= 1.639404157477051
# differential_evolution step 620: f(x)= 1.639404157477051
# differential_evolution step 621: f(x)= 1.639404157477051
# differential_evolution step 622: f(x)= 1.639404157477051
# differential_evolution step 623: f(x)= 1.639404157477051
# differential_evolution step 624: f(x)= 1.639404157477051
# differential_evolution step 625: f(x)= 1.6343020409618625
# differential_evolution step 626: f(x)= 1.6343020409618625
# differential_evolution step 627: f(x)= 1.608727044235203
# differential_evolution step 628: f(x)= 1.608727044235203
# differential_evolution step 629: f(x)= 1.594924980619051
# differential_evolution step 630: f(x)= 1.594924980619051
# differential_evolution step 631: f(x)= 1.594924980619051
# differential_evolution step 632: f(x)= 1.594924980619051
# differential_evolution step 633: f(x)= 1.594924980619051
# differential_evolution step 634: f(x)= 1.5910285572604654
# differential_evolution step 635: f(x)= 1.5368414624990836
# differential_evolution step 636: f(x)= 1.5368414624990836
# differential_evolution step 637: f(x)= 1.5368414624990836
# differential_evolution step 638: f(x)= 1.5368414624990836
# differential_evolution step 639: f(x)= 1.5368414624990836
# differential_evolution step 640: f(x)= 1.5368414624990836
# differential_evolution step 641: f(x)= 1.5368414624990836
# differential_evolution step 642: f(x)= 1.5368414624990836
# differential_evolution step 643: f(x)= 1.5368414624990836
# differential_evolution step 644: f(x)= 1.5368414624990836
# differential_evolution step 645: f(x)= 1.5368414624990836
# differential_evolution step 646: f(x)= 1.5368414624990836
# differential_evolution step 647: f(x)= 1.5368414624990836
# differential_evolution step 648: f(x)= 1.5313839649690306
# differential_evolution step 649: f(x)= 1.5313839649690306
# differential_evolution step 650: f(x)= 1.5313839649690306
# differential_evolution step 651: f(x)= 1.5313839649690306
# differential_evolution step 652: f(x)= 1.5313839649690306
# differential_evolution step 653: f(x)= 1.5313839649690306
# differential_evolution step 654: f(x)= 1.5313839649690306
# differential_evolution step 655: f(x)= 1.5313839649690306
# differential_evolution step 656: f(x)= 1.5313839649690306
# differential_evolution step 657: f(x)= 1.5313839649690306
# differential_evolution step 658: f(x)= 1.5313839649690306
# differential_evolution step 659: f(x)= 1.5313839649690306
# differential_evolution step 660: f(x)= 1.5117737887504086
# differential_evolution step 661: f(x)= 1.5117737887504086
# differential_evolution step 662: f(x)= 1.5117737887504086
# differential_evolution step 663: f(x)= 1.5077394262621895
# differential_evolution step 664: f(x)= 1.5077394262621895
# differential_evolution step 665: f(x)= 1.5077394262621895
# differential_evolution step 666: f(x)= 1.5077394262621895
# differential_evolution step 667: f(x)= 1.4964779236001817
# differential_evolution step 668: f(x)= 1.4964779236001817
# differential_evolution step 669: f(x)= 1.4964779236001817
# differential_evolution step 670: f(x)= 1.4445911711686943
# differential_evolution step 671: f(x)= 1.4445911711686943
# differential_evolution step 672: f(x)= 1.4445911711686943
# differential_evolution step 673: f(x)= 1.4445911711686943
# differential_evolution step 674: f(x)= 1.4445911711686943
# differential_evolution step 675: f(x)= 1.4445911711686943
# differential_evolution step 676: f(x)= 1.4445911711686943
# differential_evolution step 677: f(x)= 1.4445911711686943
# differential_evolution step 678: f(x)= 1.4445911711686943
# differential_evolution step 679: f(x)= 1.4445911711686943
# differential_evolution step 680: f(x)= 1.4445911711686943
# differential_evolution step 681: f(x)= 1.3999696691605579
# differential_evolution step 682: f(x)= 1.3647198933272342
# differential_evolution step 683: f(x)= 1.3647198933272342
# differential_evolution step 684: f(x)= 1.3647198933272342
# differential_evolution step 685: f(x)= 1.3647198933272342
# differential_evolution step 686: f(x)= 1.3647198933272342
# differential_evolution step 687: f(x)= 1.3588046140747736
# differential_evolution step 688: f(x)= 1.3588046140747736
# differential_evolution step 689: f(x)= 1.3588046140747736
# differential_evolution step 690: f(x)= 1.3588046140747736
# differential_evolution step 691: f(x)= 1.3588046140747736
# differential_evolution step 692: f(x)= 1.3588046140747736
# differential_evolution step 693: f(x)= 1.3554147401399048
# differential_evolution step 694: f(x)= 1.3449648352132533
# differential_evolution step 695: f(x)= 1.3449648352132533
# differential_evolution step 696: f(x)= 1.318525437081003
# differential_evolution step 697: f(x)= 1.3184092401444676
# differential_evolution step 698: f(x)= 1.3184092401444676
# differential_evolution step 699: f(x)= 1.3184092401444676
# differential_evolution step 700: f(x)= 1.3067914452081792
# differential_evolution step 701: f(x)= 1.3067914452081792
# differential_evolution step 702: f(x)= 1.3067914452081792
# differential_evolution step 703: f(x)= 1.3067914452081792
# differential_evolution step 704: f(x)= 1.3067914452081792
# differential_evolution step 705: f(x)= 1.3067914452081792
# differential_evolution step 706: f(x)= 1.3067914452081792
# differential_evolution step 707: f(x)= 1.3029538677953327
# differential_evolution step 708: f(x)= 1.3029538677953327
# differential_evolution step 709: f(x)= 1.3029538677953327
# differential_evolution step 710: f(x)= 1.3029538677953327
# differential_evolution step 711: f(x)= 1.3029538677953327
# differential_evolution step 712: f(x)= 1.3029538677953327
# differential_evolution step 713: f(x)= 1.3029538677953327
# differential_evolution step 714: f(x)= 1.3029538677953327
# differential_evolution step 715: f(x)= 1.3029538677953327
# differential_evolution step 716: f(x)= 1.3029538677953327
# differential_evolution step 717: f(x)= 1.3029538677953327
# differential_evolution step 718: f(x)= 1.3029538677953327
# differential_evolution step 719: f(x)= 1.2785949372439163
# differential_evolution step 720: f(x)= 1.2785949372439163
# differential_evolution step 721: f(x)= 1.2785949372439163
# differential_evolution step 722: f(x)= 1.2785949372439163
# differential_evolution step 723: f(x)= 1.2785949372439163
# differential_evolution step 724: f(x)= 1.2785949372439163
# differential_evolution step 725: f(x)= 1.2785949372439163
# differential_evolution step 726: f(x)= 1.2785949372439163
# differential_evolution step 727: f(x)= 1.2785949372439163
# differential_evolution step 728: f(x)= 1.2785949372439163
# differential_evolution step 729: f(x)= 1.2785949372439163
# differential_evolution step 730: f(x)= 1.2785949372439163
# differential_evolution step 731: f(x)= 1.2785949372439163
# differential_evolution step 732: f(x)= 1.2785949372439163
# differential_evolution step 733: f(x)= 1.2785949372439163
# differential_evolution step 734: f(x)= 1.2785949372439163
# differential_evolution step 735: f(x)= 1.2785949372439163
# differential_evolution step 736: f(x)= 1.2740398666920882
# differential_evolution step 737: f(x)= 1.2740398666920882
# differential_evolution step 738: f(x)= 1.2740398666920882
# differential_evolution step 739: f(x)= 1.2740398666920882
# differential_evolution step 740: f(x)= 1.2740398666920882
# differential_evolution step 741: f(x)= 1.2740398666920882
# differential_evolution step 742: f(x)= 1.2740398666920882
# differential_evolution step 743: f(x)= 1.2740398666920882
# differential_evolution step 744: f(x)= 1.2740398666920882
# differential_evolution step 745: f(x)= 1.2740398666920882
# differential_evolution step 746: f(x)= 1.2740398666920882
# differential_evolution step 747: f(x)= 1.2740398666920882
# differential_evolution step 748: f(x)= 1.2740398666920882
# differential_evolution step 749: f(x)= 1.2740398666920882
# differential_evolution step 750: f(x)= 1.2677831391058392
# differential_evolution step 751: f(x)= 1.2660666280100545
# differential_evolution step 752: f(x)= 1.2643791011189065
# differential_evolution step 753: f(x)= 1.260289488996709
# differential_evolution step 754: f(x)= 1.260289488996709
# differential_evolution step 755: f(x)= 1.260289488996709
# differential_evolution step 756: f(x)= 1.260289488996709
# differential_evolution step 757: f(x)= 1.260289488996709
# differential_evolution step 758: f(x)= 1.260289488996709
# differential_evolution step 759: f(x)= 1.260289488996709
# differential_evolution step 760: f(x)= 1.260289488996709
# differential_evolution step 761: f(x)= 1.260289488996709
# differential_evolution step 762: f(x)= 1.260289488996709
# differential_evolution step 763: f(x)= 1.260289488996709
# differential_evolution step 764: f(x)= 1.260289488996709
# differential_evolution step 765: f(x)= 1.260289488996709
# differential_evolution step 766: f(x)= 1.260289488996709
# differential_evolution step 767: f(x)= 1.2549949219960912
# differential_evolution step 768: f(x)= 1.2549949219960912
# differential_evolution step 769: f(x)= 1.2549949219960912
# differential_evolution step 770: f(x)= 1.2549949219960912
# differential_evolution step 771: f(x)= 1.2549949219960912
# differential_evolution step 772: f(x)= 1.2549949219960912
# differential_evolution step 773: f(x)= 1.2549949219960912
# differential_evolution step 774: f(x)= 1.2549949219960912
# differential_evolution step 775: f(x)= 1.2549949219960912
# differential_evolution step 776: f(x)= 1.2548537951083114
# differential_evolution step 777: f(x)= 1.2542224681673184
# differential_evolution step 778: f(x)= 1.2542224681673184
# differential_evolution step 779: f(x)= 1.2542224681673184
# differential_evolution step 780: f(x)= 1.2542224681673184
# differential_evolution step 781: f(x)= 1.2542224681673184
# differential_evolution step 782: f(x)= 1.2542224681673184
# differential_evolution step 783: f(x)= 1.2542224681673184
# differential_evolution step 784: f(x)= 1.2542224681673184
# differential_evolution step 785: f(x)= 1.2542224681673184
# differential_evolution step 786: f(x)= 1.245077315908401
# differential_evolution step 787: f(x)= 1.245077315908401
# differential_evolution step 788: f(x)= 1.245077315908401
# differential_evolution step 789: f(x)= 1.245077315908401
# differential_evolution step 790: f(x)= 1.245077315908401
# differential_evolution step 791: f(x)= 1.245077315908401
# differential_evolution step 792: f(x)= 1.245077315908401
# differential_evolution step 793: f(x)= 1.245077315908401
# differential_evolution step 794: f(x)= 1.245077315908401
# differential_evolution step 795: f(x)= 1.245077315908401
# differential_evolution step 796: f(x)= 1.245077315908401
# differential_evolution step 797: f(x)= 1.245077315908401
# differential_evolution step 798: f(x)= 1.245077315908401
# differential_evolution step 799: f(x)= 1.245077315908401
# differential_evolution step 800: f(x)= 1.245077315908401
# differential_evolution step 801: f(x)= 1.245077315908401
# differential_evolution step 802: f(x)= 1.245077315908401
# differential_evolution step 803: f(x)= 1.245077315908401
# differential_evolution step 804: f(x)= 1.245077315908401
# differential_evolution step 805: f(x)= 1.245077315908401
# differential_evolution step 806: f(x)= 1.245077315908401
# differential_evolution step 807: f(x)= 1.244858669961063
# differential_evolution step 808: f(x)= 1.244858669961063
# differential_evolution step 809: f(x)= 1.244858669961063
# differential_evolution step 810: f(x)= 1.244858669961063
# differential_evolution step 811: f(x)= 1.244858669961063
# differential_evolution step 812: f(x)= 1.2429204101739484
# differential_evolution step 813: f(x)= 1.2429204101739484
# differential_evolution step 814: f(x)= 1.2429204101739484
# differential_evolution step 815: f(x)= 1.2367431423203377
# differential_evolution step 816: f(x)= 1.2367431423203377
# differential_evolution step 817: f(x)= 1.2367431423203377
# differential_evolution step 818: f(x)= 1.234324304825173
# differential_evolution step 819: f(x)= 1.234324304825173
# differential_evolution step 820: f(x)= 1.231523157608088
# differential_evolution step 821: f(x)= 1.231523157608088
# differential_evolution step 822: f(x)= 1.231523157608088
# differential_evolution step 823: f(x)= 1.231523157608088
# differential_evolution step 824: f(x)= 1.231523157608088
# differential_evolution step 825: f(x)= 1.231523157608088
# differential_evolution step 826: f(x)= 1.231523157608088
# differential_evolution step 827: f(x)= 1.231523157608088
# differential_evolution step 828: f(x)= 1.231523157608088
# differential_evolution step 829: f(x)= 1.231523157608088
# differential_evolution step 830: f(x)= 1.231523157608088
# differential_evolution step 831: f(x)= 1.231523157608088
# differential_evolution step 832: f(x)= 1.231523157608088
# differential_evolution step 833: f(x)= 1.231523157608088
# differential_evolution step 834: f(x)= 1.2310557238794984
# differential_evolution step 835: f(x)= 1.2310557238794984
# differential_evolution step 836: f(x)= 1.2310557238794984
# differential_evolution step 837: f(x)= 1.2310557238794984
# differential_evolution step 838: f(x)= 1.2266363821189503
# differential_evolution step 839: f(x)= 1.2266363821189503
# differential_evolution step 840: f(x)= 1.2266363821189503
# differential_evolution step 841: f(x)= 1.2266363821189503
# differential_evolution step 842: f(x)= 1.2266363821189503
# differential_evolution step 843: f(x)= 1.2266363821189503
# differential_evolution step 844: f(x)= 1.2266363821189503
# differential_evolution step 845: f(x)= 1.2266363821189503
# differential_evolution step 846: f(x)= 1.2266363821189503
# differential_evolution step 847: f(x)= 1.2266363821189503
# differential_evolution step 848: f(x)= 1.2266363821189503
# differential_evolution step 849: f(x)= 1.2266363821189503
# differential_evolution step 850: f(x)= 1.2245743850075628
# differential_evolution step 851: f(x)= 1.2245743850075628
# differential_evolution step 852: f(x)= 1.2245743850075628
# differential_evolution step 853: f(x)= 1.2245743850075628
# differential_evolution step 854: f(x)= 1.2245743850075628
# differential_evolution step 855: f(x)= 1.2245743850075628
# differential_evolution step 856: f(x)= 1.2245743850075628
# differential_evolution step 857: f(x)= 1.2245743850075628
# differential_evolution step 858: f(x)= 1.2245743850075628
# differential_evolution step 859: f(x)= 1.2245743850075628
# differential_evolution step 860: f(x)= 1.2245743850075628
# differential_evolution step 861: f(x)= 1.2245743850075628
# differential_evolution step 862: f(x)= 1.2245743850075628
# differential_evolution step 863: f(x)= 1.2245743850075628
# differential_evolution step 864: f(x)= 1.2245743850075628
# differential_evolution step 865: f(x)= 1.2245743850075628
# differential_evolution step 866: f(x)= 1.2245743850075628
# differential_evolution step 867: f(x)= 1.2245743850075628
# differential_evolution step 868: f(x)= 1.2245743850075628
# differential_evolution step 869: f(x)= 1.2245743850075628
# differential_evolution step 870: f(x)= 1.2245743850075628
# differential_evolution step 871: f(x)= 1.2245743850075628
# differential_evolution step 872: f(x)= 1.2245743850075628
# differential_evolution step 873: f(x)= 1.2245743850075628
# differential_evolution step 874: f(x)= 1.2245743850075628
# differential_evolution step 875: f(x)= 1.2245743850075628
# differential_evolution step 876: f(x)= 1.2245743850075628
# differential_evolution step 877: f(x)= 1.2245743850075628
# differential_evolution step 878: f(x)= 1.2245743850075628
# differential_evolution step 879: f(x)= 1.2245743850075628
# differential_evolution step 880: f(x)= 1.2245743850075628
# differential_evolution step 881: f(x)= 1.2245743850075628
# differential_evolution step 882: f(x)= 1.2245743850075628
# differential_evolution step 883: f(x)= 1.2245743850075628
# differential_evolution step 884: f(x)= 1.2245743850075628
# differential_evolution step 885: f(x)= 1.2245743850075628
# differential_evolution step 886: f(x)= 1.2245743850075628
# differential_evolution step 887: f(x)= 1.2245743850075628
# differential_evolution step 888: f(x)= 1.2219835358520132
# differential_evolution step 889: f(x)= 1.2219835358520132
# differential_evolution step 890: f(x)= 1.2219835358520132
# differential_evolution step 891: f(x)= 1.2219835358520132
# differential_evolution step 892: f(x)= 1.2219835358520132
# differential_evolution step 893: f(x)= 1.2219835358520132
# differential_evolution step 894: f(x)= 1.2219835358520132
# differential_evolution step 895: f(x)= 1.2219835358520132
# differential_evolution step 896: f(x)= 1.2219835358520132
# differential_evolution step 897: f(x)= 1.2219835358520132
# differential_evolution step 898: f(x)= 1.2219835358520132
# differential_evolution step 899: f(x)= 1.2219835358520132
# differential_evolution step 900: f(x)= 1.2219835358520132
# differential_evolution step 901: f(x)= 1.2219835358520132
# differential_evolution step 902: f(x)= 1.2219835358520132
# differential_evolution step 903: f(x)= 1.2219835358520132
# differential_evolution step 904: f(x)= 1.2219835358520132
# differential_evolution step 905: f(x)= 1.2219835358520132
# differential_evolution step 906: f(x)= 1.2219835358520132
# differential_evolution step 907: f(x)= 1.2219835358520132
# differential_evolution step 908: f(x)= 1.2219835358520132
# differential_evolution step 909: f(x)= 1.2219835358520132
# differential_evolution step 910: f(x)= 1.2219835358520132
# differential_evolution step 911: f(x)= 1.2219835358520132
# differential_evolution step 912: f(x)= 1.2219835358520132
# differential_evolution step 913: f(x)= 1.2219835358520132
# differential_evolution step 914: f(x)= 1.2219835358520132
# differential_evolution step 915: f(x)= 1.2219835358520132
# differential_evolution step 916: f(x)= 1.2219835358520132
# differential_evolution step 917: f(x)= 1.2219835358520132
# differential_evolution step 918: f(x)= 1.2219835358520132
# differential_evolution step 919: f(x)= 1.2219835358520132
# differential_evolution step 920: f(x)= 1.2219835358520132
# differential_evolution step 921: f(x)= 1.2219835358520132
# differential_evolution step 922: f(x)= 1.2219835358520132
# differential_evolution step 923: f(x)= 1.2217297199503907
# differential_evolution step 924: f(x)= 1.2217297199503907
# differential_evolution step 925: f(x)= 1.2217297199503907
# differential_evolution step 926: f(x)= 1.2217297199503907
# differential_evolution step 927: f(x)= 1.2217297199503907
# differential_evolution step 928: f(x)= 1.2217297199503907
# differential_evolution step 929: f(x)= 1.2217297199503907
# differential_evolution step 930: f(x)= 1.2215185054033875
# differential_evolution step 931: f(x)= 1.2215185054033875
# differential_evolution step 932: f(x)= 1.2215185054033875
# differential_evolution step 933: f(x)= 1.2215185054033875
# differential_evolution step 934: f(x)= 1.2215185054033875
# differential_evolution step 935: f(x)= 1.2215185054033875
# differential_evolution step 936: f(x)= 1.2215185054033875
# differential_evolution step 937: f(x)= 1.2215185054033875
# differential_evolution step 938: f(x)= 1.2215185054033875
# differential_evolution step 939: f(x)= 1.2215185054033875
# differential_evolution step 940: f(x)= 1.2215185054033875
# differential_evolution step 941: f(x)= 1.2215185054033875
# differential_evolution step 942: f(x)= 1.2215185054033875
# differential_evolution step 943: f(x)= 1.2215185054033875
# differential_evolution step 944: f(x)= 1.2215185054033875
# differential_evolution step 945: f(x)= 1.2215185054033875
# differential_evolution step 946: f(x)= 1.2215185054033875
# differential_evolution step 947: f(x)= 1.2211663774841215
# differential_evolution step 948: f(x)= 1.2211663774841215
# differential_evolution step 949: f(x)= 1.2211663774841215
# differential_evolution step 950: f(x)= 1.2211663774841215
# differential_evolution step 951: f(x)= 1.2211663774841215
# differential_evolution step 952: f(x)= 1.2211663774841215
# differential_evolution step 953: f(x)= 1.2211663774841215
# differential_evolution step 954: f(x)= 1.2211663774841215
# differential_evolution step 955: f(x)= 1.2211663774841215
# differential_evolution step 956: f(x)= 1.2211663774841215
# differential_evolution step 957: f(x)= 1.2211663774841215
# differential_evolution step 958: f(x)= 1.2211663774841215
# differential_evolution step 959: f(x)= 1.2211663774841215
# differential_evolution step 960: f(x)= 1.2211663774841215
# differential_evolution step 961: f(x)= 1.2211663774841215
# differential_evolution step 962: f(x)= 1.2211663774841215
# differential_evolution step 963: f(x)= 1.2211663774841215
# differential_evolution step 964: f(x)= 1.2211663774841215
# differential_evolution step 965: f(x)= 1.2211663774841215
# differential_evolution step 966: f(x)= 1.2211663774841215
# differential_evolution step 967: f(x)= 1.221054632494221
# differential_evolution step 968: f(x)= 1.2210530834023485
# differential_evolution step 969: f(x)= 1.2210530834023485
# differential_evolution step 970: f(x)= 1.2210530834023485
# differential_evolution step 971: f(x)= 1.2206792213024036
# differential_evolution step 972: f(x)= 1.2206792213024036
# differential_evolution step 973: f(x)= 1.2206792213024036
# differential_evolution step 974: f(x)= 1.2206792213024036
# differential_evolution step 975: f(x)= 1.2206792213024036
# differential_evolution step 976: f(x)= 1.2206792213024036
# differential_evolution step 977: f(x)= 1.2205576236149736
# differential_evolution step 978: f(x)= 1.2205576236149736
# differential_evolution step 979: f(x)= 1.2205576236149736
# differential_evolution step 980: f(x)= 1.2205576236149736
# differential_evolution step 981: f(x)= 1.2205576236149736
# differential_evolution step 982: f(x)= 1.2205576236149736
# differential_evolution step 983: f(x)= 1.2205576236149736
# differential_evolution step 984: f(x)= 1.2205576236149736
# differential_evolution step 985: f(x)= 1.2205576236149736
# differential_evolution step 986: f(x)= 1.2205576236149736
# differential_evolution step 987: f(x)= 1.2205576236149736
# differential_evolution step 988: f(x)= 1.2205576236149736
# differential_evolution step 989: f(x)= 1.2205576236149736
# differential_evolution step 990: f(x)= 1.2205576236149736
# differential_evolution step 991: f(x)= 1.2205576236149736
# differential_evolution step 992: f(x)= 1.2205576236149736
# differential_evolution step 993: f(x)= 1.2205576236149736
# differential_evolution step 994: f(x)= 1.2205576236149736
# differential_evolution step 995: f(x)= 1.2205576236149736
# differential_evolution step 996: f(x)= 1.2205576236149736
# differential_evolution step 997: f(x)= 1.2205576236149736
# differential_evolution step 998: f(x)= 1.2205576236149736
# differential_evolution step 999: f(x)= 1.2205576236149736
# differential_evolution step 1000: f(x)= 1.2205576236149736
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.1235, r_e=6.2840, n=1.0156, x_0=44.8199
# Sérsic 2: I_e=0.4074, r_e=26.8555, n=1.7303, x_0=51.5999
# Sérsic 3: I_e=3.4945, r_e=4.5297, n=0.6192, x_0=60.5508
# Chi quadro minimo: 1.2200531334505744
# False

# %%
# Plots:
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Sérsic 1: I_e=1.1235, r_e=6.2840, n=1.0156, x_0=44.8199
# Sérsic 2: I_e=0.4074, r_e=26.8555, n=1.7303, x_0=51.5999
# Sérsic 3: I_e=3.4945, r_e=4.5297, n=0.6192, x_0=60.5508
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Diff_params/NII_fit_diff.csv", index_col=0)
initial_guesses = np.concatenate([
    df['Component 1'].values,  # [I_e, r_e, n, x_0] per Component 1
    df['Component 2'].values,  # [I_e, r_e, n, x_0] per Component 2
    df['Component 3'].values   # [I_e, r_e, n, x_0] per Component 3
])
print(df)
bounds = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (38, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 5),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 5),
    (60, 80),
    (0.1, 10),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2),
]
# Out:
#      Component 1  Component 2  Component 3
# I_e       1.8563       3.2521       0.0782
# r_e      13.2779       1.3882      69.9999
# n         1.9567       0.3369       2.6190
# x_0      38.3854      48.6767      80.8290

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=initial_guesses, sigma = real_errors_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.6083, r_e=26.3448, n=2.8075, x_0=38.0141
# Sérsic 2: I_e=0.5335, r_e=5.0000, n=1.6107, x_0=48.7608
# Sérsic 3: I_e=0.0612, r_e=60.0007, n=2.8947, x_0=80.5449
# [ 0.22951821  6.53167256  0.3407292   0.14686709  0.63700734  3.9523385
#   0.95441887  0.29909448  0.08818186 70.94000255  1.02201055  0.20906013]
# 14.142167383089662

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[3])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 20096.148536658726
# differential_evolution step 2: f(x)= 20096.148536658726
# differential_evolution step 3: f(x)= 20096.148536658726
# differential_evolution step 4: f(x)= 20096.148536658726
# differential_evolution step 5: f(x)= 20096.148536658726
# differential_evolution step 6: f(x)= 20096.148536658726
# differential_evolution step 7: f(x)= 12885.161682716976
# differential_evolution step 8: f(x)= 80.15855705842341
# differential_evolution step 9: f(x)= 80.15855705842341
# differential_evolution step 10: f(x)= 80.15855705842341
# differential_evolution step 11: f(x)= 80.15855705842341
# differential_evolution step 12: f(x)= 80.15855705842341
# differential_evolution step 13: f(x)= 80.15855705842341
# differential_evolution step 14: f(x)= 80.15855705842341
# differential_evolution step 15: f(x)= 80.15855705842341
# differential_evolution step 16: f(x)= 80.15855705842341
# differential_evolution step 17: f(x)= 58.99247462815807
# differential_evolution step 18: f(x)= 58.99247462815807
# differential_evolution step 19: f(x)= 58.99247462815807
# differential_evolution step 20: f(x)= 58.99247462815807
# differential_evolution step 21: f(x)= 56.18620157190531
# differential_evolution step 22: f(x)= 56.18620157190531
# differential_evolution step 23: f(x)= 56.18620157190531
# differential_evolution step 24: f(x)= 56.18620157190531
# differential_evolution step 25: f(x)= 56.18620157190531
# differential_evolution step 26: f(x)= 56.18620157190531
# differential_evolution step 27: f(x)= 56.18620157190531
# differential_evolution step 28: f(x)= 56.18620157190531
# differential_evolution step 29: f(x)= 56.18620157190531
# differential_evolution step 30: f(x)= 32.13013665827395
# differential_evolution step 31: f(x)= 32.13013665827395
# differential_evolution step 32: f(x)= 32.13013665827395
# differential_evolution step 33: f(x)= 32.13013665827395
# differential_evolution step 34: f(x)= 22.955085754311295
# differential_evolution step 35: f(x)= 22.955085754311295
# differential_evolution step 36: f(x)= 22.955085754311295
# differential_evolution step 37: f(x)= 19.97088986385699
# differential_evolution step 38: f(x)= 19.97088986385699
# differential_evolution step 39: f(x)= 19.97088986385699
# differential_evolution step 40: f(x)= 16.34190161256664
# differential_evolution step 41: f(x)= 16.34190161256664
# differential_evolution step 42: f(x)= 15.494145644887222
# differential_evolution step 43: f(x)= 15.494145644887222
# differential_evolution step 44: f(x)= 8.58417478461241
# differential_evolution step 45: f(x)= 8.58417478461241
# differential_evolution step 46: f(x)= 8.58417478461241
# differential_evolution step 47: f(x)= 8.58417478461241
# differential_evolution step 48: f(x)= 8.58417478461241
# differential_evolution step 49: f(x)= 8.58417478461241
# differential_evolution step 50: f(x)= 7.529297700378143
# differential_evolution step 51: f(x)= 7.529297700378143
# differential_evolution step 52: f(x)= 7.529297700378143
# differential_evolution step 53: f(x)= 7.529297700378143
# differential_evolution step 54: f(x)= 7.443974739676255
# differential_evolution step 55: f(x)= 7.443974739676255
# differential_evolution step 56: f(x)= 6.989417345915348
# differential_evolution step 57: f(x)= 5.0354835941045515
# differential_evolution step 58: f(x)= 4.773543907897909
# differential_evolution step 59: f(x)= 4.773543907897909
# differential_evolution step 60: f(x)= 4.773543907897909
# differential_evolution step 61: f(x)= 4.773543907897909
# differential_evolution step 62: f(x)= 4.773543907897909
# differential_evolution step 63: f(x)= 4.707923411829575
# differential_evolution step 64: f(x)= 4.707923411829575
# differential_evolution step 65: f(x)= 4.707923411829575
# differential_evolution step 66: f(x)= 4.707923411829575
# differential_evolution step 67: f(x)= 4.707923411829575
# differential_evolution step 68: f(x)= 4.707923411829575
# differential_evolution step 69: f(x)= 4.707923411829575
# differential_evolution step 70: f(x)= 3.347891249517004
# differential_evolution step 71: f(x)= 3.347891249517004
# differential_evolution step 72: f(x)= 3.347891249517004
# differential_evolution step 73: f(x)= 3.347891249517004
# differential_evolution step 74: f(x)= 3.347891249517004
# differential_evolution step 75: f(x)= 3.347891249517004
# differential_evolution step 76: f(x)= 3.347891249517004
# differential_evolution step 77: f(x)= 3.347891249517004
# differential_evolution step 78: f(x)= 2.7506469307858694
# differential_evolution step 79: f(x)= 2.7506469307858694
# differential_evolution step 80: f(x)= 2.7506469307858694
# differential_evolution step 81: f(x)= 2.7506469307858694
# differential_evolution step 82: f(x)= 2.7506469307858694
# differential_evolution step 83: f(x)= 2.7506469307858694
# differential_evolution step 84: f(x)= 2.7506469307858694
# differential_evolution step 85: f(x)= 2.7506469307858694
# differential_evolution step 86: f(x)= 2.7506469307858694
# differential_evolution step 87: f(x)= 2.7506469307858694
# differential_evolution step 88: f(x)= 2.7506469307858694
# differential_evolution step 89: f(x)= 2.7506469307858694
# differential_evolution step 90: f(x)= 2.7506469307858694
# differential_evolution step 91: f(x)= 2.7506469307858694
# differential_evolution step 92: f(x)= 2.7506469307858694
# differential_evolution step 93: f(x)= 2.7506469307858694
# differential_evolution step 94: f(x)= 2.7506469307858694
# differential_evolution step 95: f(x)= 2.7506469307858694
# differential_evolution step 96: f(x)= 2.7506469307858694
# differential_evolution step 97: f(x)= 2.7506469307858694
# differential_evolution step 98: f(x)= 2.732431090185826
# differential_evolution step 99: f(x)= 2.732431090185826
# differential_evolution step 100: f(x)= 2.732431090185826
# differential_evolution step 101: f(x)= 2.732431090185826
# differential_evolution step 102: f(x)= 2.732431090185826
# differential_evolution step 103: f(x)= 2.732431090185826
# differential_evolution step 104: f(x)= 2.732431090185826
# differential_evolution step 105: f(x)= 2.5451526042612764
# differential_evolution step 106: f(x)= 2.5451526042612764
# differential_evolution step 107: f(x)= 2.5451526042612764
# differential_evolution step 108: f(x)= 2.5451526042612764
# differential_evolution step 109: f(x)= 2.5451526042612764
# differential_evolution step 110: f(x)= 2.5451526042612764
# differential_evolution step 111: f(x)= 2.4135393559223215
# differential_evolution step 112: f(x)= 2.4135393559223215
# differential_evolution step 113: f(x)= 2.4135393559223215
# differential_evolution step 114: f(x)= 2.4135393559223215
# differential_evolution step 115: f(x)= 2.334106735469936
# differential_evolution step 116: f(x)= 2.334106735469936
# differential_evolution step 117: f(x)= 2.334106735469936
# differential_evolution step 118: f(x)= 2.334106735469936
# differential_evolution step 119: f(x)= 2.334106735469936
# differential_evolution step 120: f(x)= 2.334106735469936
# differential_evolution step 121: f(x)= 2.334106735469936
# differential_evolution step 122: f(x)= 2.334106735469936
# differential_evolution step 123: f(x)= 2.334106735469936
# differential_evolution step 124: f(x)= 1.9491707488802181
# differential_evolution step 125: f(x)= 1.9491707488802181
# differential_evolution step 126: f(x)= 1.9491707488802181
# differential_evolution step 127: f(x)= 1.8420063755117926
# differential_evolution step 128: f(x)= 1.8420063755117926
# differential_evolution step 129: f(x)= 1.8420063755117926
# differential_evolution step 130: f(x)= 1.8194121552960396
# differential_evolution step 131: f(x)= 1.8194121552960396
# differential_evolution step 132: f(x)= 1.8194121552960396
# differential_evolution step 133: f(x)= 1.8194121552960396
# differential_evolution step 134: f(x)= 1.8194121552960396
# differential_evolution step 135: f(x)= 1.8194121552960396
# differential_evolution step 136: f(x)= 1.8194121552960396
# differential_evolution step 137: f(x)= 1.6710711049518685
# differential_evolution step 138: f(x)= 1.6710711049518685
# differential_evolution step 139: f(x)= 1.6710711049518685
# differential_evolution step 140: f(x)= 1.6710711049518685
# differential_evolution step 141: f(x)= 1.6710711049518685
# differential_evolution step 142: f(x)= 1.6710711049518685
# differential_evolution step 143: f(x)= 1.6710711049518685
# differential_evolution step 144: f(x)= 1.6710711049518685
# differential_evolution step 145: f(x)= 1.6710711049518685
# differential_evolution step 146: f(x)= 1.6710711049518685
# differential_evolution step 147: f(x)= 1.6710711049518685
# differential_evolution step 148: f(x)= 1.6710711049518685
# differential_evolution step 149: f(x)= 1.6710711049518685
# differential_evolution step 150: f(x)= 1.4689342358556539
# differential_evolution step 151: f(x)= 1.4689342358556539
# differential_evolution step 152: f(x)= 1.4689342358556539
# differential_evolution step 153: f(x)= 1.4689342358556539
# differential_evolution step 154: f(x)= 1.4689342358556539
# differential_evolution step 155: f(x)= 1.4689342358556539
# differential_evolution step 156: f(x)= 1.4689342358556539
# differential_evolution step 157: f(x)= 1.4689342358556539
# differential_evolution step 158: f(x)= 1.4689342358556539
# differential_evolution step 159: f(x)= 1.4689342358556539
# differential_evolution step 160: f(x)= 1.4689342358556539
# differential_evolution step 161: f(x)= 1.3343014190919924
# differential_evolution step 162: f(x)= 1.3343014190919924
# differential_evolution step 163: f(x)= 1.3343014190919924
# differential_evolution step 164: f(x)= 1.3343014190919924
# differential_evolution step 165: f(x)= 1.3343014190919924
# differential_evolution step 166: f(x)= 1.3343014190919924
# differential_evolution step 167: f(x)= 1.3343014190919924
# differential_evolution step 168: f(x)= 1.3343014190919924
# differential_evolution step 169: f(x)= 1.3343014190919924
# differential_evolution step 170: f(x)= 1.3343014190919924
# differential_evolution step 171: f(x)= 1.3343014190919924
# differential_evolution step 172: f(x)= 1.3343014190919924
# differential_evolution step 173: f(x)= 1.3343014190919924
# differential_evolution step 174: f(x)= 1.3343014190919924
# differential_evolution step 175: f(x)= 1.3343014190919924
# differential_evolution step 176: f(x)= 1.3343014190919924
# differential_evolution step 177: f(x)= 1.3343014190919924
# differential_evolution step 178: f(x)= 1.3343014190919924
# differential_evolution step 179: f(x)= 1.3343014190919924
# differential_evolution step 180: f(x)= 1.3343014190919924
# differential_evolution step 181: f(x)= 1.3343014190919924
# differential_evolution step 182: f(x)= 1.3343014190919924
# differential_evolution step 183: f(x)= 1.3140351909391417
# differential_evolution step 184: f(x)= 1.3140351909391417
# differential_evolution step 185: f(x)= 1.3140351909391417
# differential_evolution step 186: f(x)= 1.3140351909391417
# differential_evolution step 187: f(x)= 1.3140351909391417
# differential_evolution step 188: f(x)= 1.3140351909391417
# differential_evolution step 189: f(x)= 1.3140351909391417
# differential_evolution step 190: f(x)= 1.3140351909391417
# differential_evolution step 191: f(x)= 1.3140351909391417
# differential_evolution step 192: f(x)= 1.3140351909391417
# differential_evolution step 193: f(x)= 1.313922461936796
# differential_evolution step 194: f(x)= 1.313922461936796
# differential_evolution step 195: f(x)= 1.313922461936796
# differential_evolution step 196: f(x)= 1.313922461936796
# differential_evolution step 197: f(x)= 1.313922461936796
# differential_evolution step 198: f(x)= 1.313922461936796
# differential_evolution step 199: f(x)= 1.313922461936796
# differential_evolution step 200: f(x)= 1.313922461936796
# differential_evolution step 201: f(x)= 1.313922461936796
# differential_evolution step 202: f(x)= 1.313922461936796
# differential_evolution step 203: f(x)= 1.313922461936796
# differential_evolution step 204: f(x)= 1.313922461936796
# differential_evolution step 205: f(x)= 1.3052247361942808
# differential_evolution step 206: f(x)= 1.3052247361942808
# differential_evolution step 207: f(x)= 1.3052247361942808
# differential_evolution step 208: f(x)= 1.3052247361942808
# differential_evolution step 209: f(x)= 1.3052247361942808
# differential_evolution step 210: f(x)= 1.2756141770343272
# differential_evolution step 211: f(x)= 1.266160832575584
# differential_evolution step 212: f(x)= 1.201083618329349
# differential_evolution step 213: f(x)= 1.201083618329349
# differential_evolution step 214: f(x)= 1.201083618329349
# differential_evolution step 215: f(x)= 1.201083618329349
# differential_evolution step 216: f(x)= 1.201083618329349
# differential_evolution step 217: f(x)= 1.201083618329349
# differential_evolution step 218: f(x)= 1.201083618329349
# differential_evolution step 219: f(x)= 1.201083618329349
# differential_evolution step 220: f(x)= 1.201083618329349
# differential_evolution step 221: f(x)= 1.201083618329349
# differential_evolution step 222: f(x)= 1.201083618329349
# differential_evolution step 223: f(x)= 1.201083618329349
# differential_evolution step 224: f(x)= 1.201083618329349
# differential_evolution step 225: f(x)= 1.201083618329349
# differential_evolution step 226: f(x)= 1.201083618329349
# differential_evolution step 227: f(x)= 1.201083618329349
# differential_evolution step 228: f(x)= 1.201083618329349
# differential_evolution step 229: f(x)= 1.201083618329349
# differential_evolution step 230: f(x)= 1.120380870806731
# differential_evolution step 231: f(x)= 1.120380870806731
# differential_evolution step 232: f(x)= 1.120380870806731
# differential_evolution step 233: f(x)= 1.120380870806731
# differential_evolution step 234: f(x)= 1.120380870806731
# differential_evolution step 235: f(x)= 1.120380870806731
# differential_evolution step 236: f(x)= 1.120380870806731
# differential_evolution step 237: f(x)= 1.120380870806731
# differential_evolution step 238: f(x)= 1.1014626921964277
# differential_evolution step 239: f(x)= 1.1014626921964277
# differential_evolution step 240: f(x)= 1.1014626921964277
# differential_evolution step 241: f(x)= 1.1014626921964277
# differential_evolution step 242: f(x)= 1.1014626921964277
# differential_evolution step 243: f(x)= 1.1014626921964277
# differential_evolution step 244: f(x)= 1.1014626921964277
# differential_evolution step 245: f(x)= 1.1014626921964277
# differential_evolution step 246: f(x)= 1.1014626921964277
# differential_evolution step 247: f(x)= 1.1014626921964277
# differential_evolution step 248: f(x)= 1.1014626921964277
# differential_evolution step 249: f(x)= 1.1014626921964277
# differential_evolution step 250: f(x)= 1.1014626921964277
# differential_evolution step 251: f(x)= 1.1014626921964277
# differential_evolution step 252: f(x)= 1.1014626921964277
# differential_evolution step 253: f(x)= 1.0838026332320996
# differential_evolution step 254: f(x)= 1.0838026332320996
# differential_evolution step 255: f(x)= 1.0838026332320996
# differential_evolution step 256: f(x)= 1.0745833537274512
# differential_evolution step 257: f(x)= 1.0745833537274512
# differential_evolution step 258: f(x)= 1.0745833537274512
# differential_evolution step 259: f(x)= 1.0745833537274512
# differential_evolution step 260: f(x)= 1.0745833537274512
# differential_evolution step 261: f(x)= 1.0745833537274512
# differential_evolution step 262: f(x)= 1.0745833537274512
# differential_evolution step 263: f(x)= 1.0745833537274512
# differential_evolution step 264: f(x)= 1.0745833537274512
# differential_evolution step 265: f(x)= 1.0745833537274512
# differential_evolution step 266: f(x)= 1.0619371990833875
# differential_evolution step 267: f(x)= 1.0539175304014765
# differential_evolution step 268: f(x)= 1.0539175304014765
# differential_evolution step 269: f(x)= 1.0327759272034733
# differential_evolution step 270: f(x)= 1.0327759272034733
# differential_evolution step 271: f(x)= 0.9934319597280125
# differential_evolution step 272: f(x)= 0.9934319597280125
# differential_evolution step 273: f(x)= 0.9934319597280125
# differential_evolution step 274: f(x)= 0.9934319597280125
# differential_evolution step 275: f(x)= 0.9934319597280125
# differential_evolution step 276: f(x)= 0.9934319597280125
# differential_evolution step 277: f(x)= 0.9934319597280125
# differential_evolution step 278: f(x)= 0.9844151817212702
# differential_evolution step 279: f(x)= 0.9844151817212702
# differential_evolution step 280: f(x)= 0.9844151817212702
# differential_evolution step 281: f(x)= 0.9844151817212702
# differential_evolution step 282: f(x)= 0.9844151817212702
# differential_evolution step 283: f(x)= 0.9844151817212702
# differential_evolution step 284: f(x)= 0.9844151817212702
# differential_evolution step 285: f(x)= 0.9844151817212702
# differential_evolution step 286: f(x)= 0.9844151817212702
# differential_evolution step 287: f(x)= 0.9844151817212702
# differential_evolution step 288: f(x)= 0.9844151817212702
# differential_evolution step 289: f(x)= 0.9844151817212702
# differential_evolution step 290: f(x)= 0.9844151817212702
# differential_evolution step 291: f(x)= 0.9844151817212702
# differential_evolution step 292: f(x)= 0.9844151817212702
# differential_evolution step 293: f(x)= 0.9780299507694283
# differential_evolution step 294: f(x)= 0.9780299507694283
# differential_evolution step 295: f(x)= 0.9780299507694283
# differential_evolution step 296: f(x)= 0.9780299507694283
# differential_evolution step 297: f(x)= 0.9652289241307259
# differential_evolution step 298: f(x)= 0.9652289241307259
# differential_evolution step 299: f(x)= 0.9652289241307259
# differential_evolution step 300: f(x)= 0.9652289241307259
# differential_evolution step 301: f(x)= 0.9652289241307259
# differential_evolution step 302: f(x)= 0.9652289241307259
# differential_evolution step 303: f(x)= 0.9652289241307259
# differential_evolution step 304: f(x)= 0.9652289241307259
# differential_evolution step 305: f(x)= 0.9652289241307259
# differential_evolution step 306: f(x)= 0.9652289241307259
# differential_evolution step 307: f(x)= 0.9652289241307259
# differential_evolution step 308: f(x)= 0.9541757905407335
# differential_evolution step 309: f(x)= 0.9541757905407335
# differential_evolution step 310: f(x)= 0.9448754507302803
# differential_evolution step 311: f(x)= 0.9448754507302803
# differential_evolution step 312: f(x)= 0.9448754507302803
# differential_evolution step 313: f(x)= 0.9448754507302803
# differential_evolution step 314: f(x)= 0.9448754507302803
# differential_evolution step 315: f(x)= 0.9448754507302803
# differential_evolution step 316: f(x)= 0.9256106748687685
# differential_evolution step 317: f(x)= 0.9256106748687685
# differential_evolution step 318: f(x)= 0.9256106748687685
# differential_evolution step 319: f(x)= 0.9256106748687685
# differential_evolution step 320: f(x)= 0.9256106748687685
# differential_evolution step 321: f(x)= 0.9256106748687685
# differential_evolution step 322: f(x)= 0.9256106748687685
# differential_evolution step 323: f(x)= 0.9256106748687685
# differential_evolution step 324: f(x)= 0.9256106748687685
# differential_evolution step 325: f(x)= 0.9256106748687685
# differential_evolution step 326: f(x)= 0.9256106748687685
# differential_evolution step 327: f(x)= 0.9256106748687685
# differential_evolution step 328: f(x)= 0.9256106748687685
# differential_evolution step 329: f(x)= 0.9256106748687685
# differential_evolution step 330: f(x)= 0.9256106748687685
# differential_evolution step 331: f(x)= 0.9256106748687685
# differential_evolution step 332: f(x)= 0.9256106748687685
# differential_evolution step 333: f(x)= 0.9256106748687685
# differential_evolution step 334: f(x)= 0.9256106748687685
# differential_evolution step 335: f(x)= 0.9256106748687685
# differential_evolution step 336: f(x)= 0.9256106748687685
# differential_evolution step 337: f(x)= 0.9256106748687685
# differential_evolution step 338: f(x)= 0.9180334684520504
# differential_evolution step 339: f(x)= 0.9180334684520504
# differential_evolution step 340: f(x)= 0.9154181349453593
# differential_evolution step 341: f(x)= 0.9154181349453593
# differential_evolution step 342: f(x)= 0.9075576595717917
# differential_evolution step 343: f(x)= 0.9075576595717917
# differential_evolution step 344: f(x)= 0.9075576595717917
# differential_evolution step 345: f(x)= 0.9075576595717917
# differential_evolution step 346: f(x)= 0.9075576595717917
# differential_evolution step 347: f(x)= 0.9075576595717917
# differential_evolution step 348: f(x)= 0.9075576595717917
# differential_evolution step 349: f(x)= 0.9075576595717917
# differential_evolution step 350: f(x)= 0.9075576595717917
# differential_evolution step 351: f(x)= 0.9075576595717917
# differential_evolution step 352: f(x)= 0.9075576595717917
# differential_evolution step 353: f(x)= 0.9065597339534254
# differential_evolution step 354: f(x)= 0.9065597339534254
# differential_evolution step 355: f(x)= 0.9065597339534254
# differential_evolution step 356: f(x)= 0.9065597339534254
# differential_evolution step 357: f(x)= 0.9065597339534254
# differential_evolution step 358: f(x)= 0.9065597339534254
# differential_evolution step 359: f(x)= 0.9065597339534254
# differential_evolution step 360: f(x)= 0.9065597339534254
# differential_evolution step 361: f(x)= 0.9065597339534254
# differential_evolution step 362: f(x)= 0.9065597339534254
# differential_evolution step 363: f(x)= 0.900954999993777
# differential_evolution step 364: f(x)= 0.8967226952407829
# differential_evolution step 365: f(x)= 0.8967226952407829
# differential_evolution step 366: f(x)= 0.8967226952407829
# differential_evolution step 367: f(x)= 0.8967226952407829
# differential_evolution step 368: f(x)= 0.8967226952407829
# differential_evolution step 369: f(x)= 0.8967226952407829
# differential_evolution step 370: f(x)= 0.8967226952407829
# differential_evolution step 371: f(x)= 0.8967226952407829
# differential_evolution step 372: f(x)= 0.8967226952407829
# differential_evolution step 373: f(x)= 0.8967226952407829
# differential_evolution step 374: f(x)= 0.8967226952407829
# differential_evolution step 375: f(x)= 0.8967226952407829
# differential_evolution step 376: f(x)= 0.8967226952407829
# differential_evolution step 377: f(x)= 0.8967226952407829
# differential_evolution step 378: f(x)= 0.8967226952407829
# differential_evolution step 379: f(x)= 0.8967226952407829
# differential_evolution step 380: f(x)= 0.8967226952407829
# differential_evolution step 381: f(x)= 0.8967226952407829
# differential_evolution step 382: f(x)= 0.8967226952407829
# differential_evolution step 383: f(x)= 0.8959807215857312
# differential_evolution step 384: f(x)= 0.8958541264438334
# differential_evolution step 385: f(x)= 0.8958541264438334
# differential_evolution step 386: f(x)= 0.8944330107994644
# differential_evolution step 387: f(x)= 0.8944330107994644
# differential_evolution step 388: f(x)= 0.8944330107994644
# differential_evolution step 389: f(x)= 0.8944330107994644
# differential_evolution step 390: f(x)= 0.8942698826554396
# differential_evolution step 391: f(x)= 0.8942698826554396
# differential_evolution step 392: f(x)= 0.893775365788634
# differential_evolution step 393: f(x)= 0.8903828477058788
# differential_evolution step 394: f(x)= 0.8903828477058788
# differential_evolution step 395: f(x)= 0.8903828477058788
# differential_evolution step 396: f(x)= 0.8903828477058788
# differential_evolution step 397: f(x)= 0.8878933711761486
# differential_evolution step 398: f(x)= 0.8878933711761486
# differential_evolution step 399: f(x)= 0.8878933711761486
# differential_evolution step 400: f(x)= 0.8878933711761486
# differential_evolution step 401: f(x)= 0.8878933711761486
# differential_evolution step 402: f(x)= 0.8878933711761486
# differential_evolution step 403: f(x)= 0.8878933711761486
# differential_evolution step 404: f(x)= 0.8878933711761486
# differential_evolution step 405: f(x)= 0.8878933711761486
# differential_evolution step 406: f(x)= 0.8878933711761486
# differential_evolution step 407: f(x)= 0.8878933711761486
# differential_evolution step 408: f(x)= 0.8878933711761486
# differential_evolution step 409: f(x)= 0.8878933711761486
# differential_evolution step 410: f(x)= 0.8878933711761486
# differential_evolution step 411: f(x)= 0.8878933711761486
# differential_evolution step 412: f(x)= 0.8878933711761486
# differential_evolution step 413: f(x)= 0.8878933711761486
# differential_evolution step 414: f(x)= 0.8868277349959686
# differential_evolution step 415: f(x)= 0.8868277349959686
# differential_evolution step 416: f(x)= 0.8798491927514278
# differential_evolution step 417: f(x)= 0.8798491927514278
# differential_evolution step 418: f(x)= 0.8798491927514278
# differential_evolution step 419: f(x)= 0.8798491927514278
# differential_evolution step 420: f(x)= 0.8798491927514278
# differential_evolution step 421: f(x)= 0.8798491927514278
# differential_evolution step 422: f(x)= 0.8798491927514278
# differential_evolution step 423: f(x)= 0.8798491927514278
# differential_evolution step 424: f(x)= 0.8798491927514278
# differential_evolution step 425: f(x)= 0.8798491927514278
# differential_evolution step 426: f(x)= 0.8798491927514278
# differential_evolution step 427: f(x)= 0.8798491927514278
# differential_evolution step 428: f(x)= 0.8798491927514278
# differential_evolution step 429: f(x)= 0.8798491927514278
# differential_evolution step 430: f(x)= 0.8798491927514278
# differential_evolution step 431: f(x)= 0.8798491927514278
# differential_evolution step 432: f(x)= 0.8783229234630311
# differential_evolution step 433: f(x)= 0.8783229234630311
# differential_evolution step 434: f(x)= 0.8783229234630311
# differential_evolution step 435: f(x)= 0.8783229234630311
# differential_evolution step 436: f(x)= 0.8783229234630311
# differential_evolution step 437: f(x)= 0.8783229234630311
# differential_evolution step 438: f(x)= 0.8783229234630311
# differential_evolution step 439: f(x)= 0.8783229234630311
# differential_evolution step 440: f(x)= 0.8783229234630311
# differential_evolution step 441: f(x)= 0.8783121125014799
# differential_evolution step 442: f(x)= 0.8783121125014799
# differential_evolution step 443: f(x)= 0.8783121125014799
# differential_evolution step 444: f(x)= 0.8783121125014799
# differential_evolution step 445: f(x)= 0.8783121125014799
# differential_evolution step 446: f(x)= 0.8762656801249485
# differential_evolution step 447: f(x)= 0.8762656801249485
# differential_evolution step 448: f(x)= 0.8762656801249485
# differential_evolution step 449: f(x)= 0.8762656801249485
# differential_evolution step 450: f(x)= 0.8762656801249485
# differential_evolution step 451: f(x)= 0.8762656801249485
# differential_evolution step 452: f(x)= 0.8762656801249485
# differential_evolution step 453: f(x)= 0.8762656801249485
# differential_evolution step 454: f(x)= 0.8762656801249485
# differential_evolution step 455: f(x)= 0.8762656801249485
# differential_evolution step 456: f(x)= 0.8762656801249485
# differential_evolution step 457: f(x)= 0.8762656801249485
# differential_evolution step 458: f(x)= 0.8762656801249485
# differential_evolution step 459: f(x)= 0.8762656801249485
# differential_evolution step 460: f(x)= 0.8762656801249485
# differential_evolution step 461: f(x)= 0.8762656801249485
# differential_evolution step 462: f(x)= 0.8762656801249485
# differential_evolution step 463: f(x)= 0.8729290189092597
# differential_evolution step 464: f(x)= 0.8729290189092597
# differential_evolution step 465: f(x)= 0.8729290189092597
# differential_evolution step 466: f(x)= 0.8729290189092597
# differential_evolution step 467: f(x)= 0.8729290189092597
# differential_evolution step 468: f(x)= 0.8729290189092597
# differential_evolution step 469: f(x)= 0.8729290189092597
# differential_evolution step 470: f(x)= 0.8729290189092597
# differential_evolution step 471: f(x)= 0.8729290189092597
# differential_evolution step 472: f(x)= 0.8722847515647512
# differential_evolution step 473: f(x)= 0.8722847515647512
# differential_evolution step 474: f(x)= 0.8722847515647512
# differential_evolution step 475: f(x)= 0.8722847515647512
# differential_evolution step 476: f(x)= 0.8722847515647512
# differential_evolution step 477: f(x)= 0.8722847515647512
# differential_evolution step 478: f(x)= 0.8713879063094819
# differential_evolution step 479: f(x)= 0.8713879063094819
# differential_evolution step 480: f(x)= 0.8713879063094819
# differential_evolution step 481: f(x)= 0.871060846557974
# differential_evolution step 482: f(x)= 0.871060846557974
# differential_evolution step 483: f(x)= 0.871060846557974
# differential_evolution step 484: f(x)= 0.871060846557974
# differential_evolution step 485: f(x)= 0.871060846557974
# differential_evolution step 486: f(x)= 0.871060846557974
# differential_evolution step 487: f(x)= 0.871060846557974
# differential_evolution step 488: f(x)= 0.871060846557974
# differential_evolution step 489: f(x)= 0.871060846557974
# differential_evolution step 490: f(x)= 0.8685387064242185
# differential_evolution step 491: f(x)= 0.8685387064242185
# differential_evolution step 492: f(x)= 0.8685387064242185
# differential_evolution step 493: f(x)= 0.8685387064242185
# differential_evolution step 494: f(x)= 0.8685387064242185
# differential_evolution step 495: f(x)= 0.8685387064242185
# differential_evolution step 496: f(x)= 0.8685387064242185
# differential_evolution step 497: f(x)= 0.8685387064242185
# differential_evolution step 498: f(x)= 0.8685387064242185
# differential_evolution step 499: f(x)= 0.8685387064242185
# differential_evolution step 500: f(x)= 0.8685387064242185
# differential_evolution step 501: f(x)= 0.8685387064242185
# differential_evolution step 502: f(x)= 0.8685387064242185
# differential_evolution step 503: f(x)= 0.8685387064242185
# differential_evolution step 504: f(x)= 0.8685387064242185
# differential_evolution step 505: f(x)= 0.8685387064242185
# differential_evolution step 506: f(x)= 0.8685387064242185
# differential_evolution step 507: f(x)= 0.8685387064242185
# differential_evolution step 508: f(x)= 0.8685387064242185
# differential_evolution step 509: f(x)= 0.8685387064242185
# differential_evolution step 510: f(x)= 0.8685387064242185
# differential_evolution step 511: f(x)= 0.8685387064242185
# differential_evolution step 512: f(x)= 0.8685387064242185
# differential_evolution step 513: f(x)= 0.8680006450950295
# differential_evolution step 514: f(x)= 0.8680006450950295
# differential_evolution step 515: f(x)= 0.8680006450950295
# differential_evolution step 516: f(x)= 0.8680006450950295
# differential_evolution step 517: f(x)= 0.8680006450950295
# differential_evolution step 518: f(x)= 0.8680006450950295
# differential_evolution step 519: f(x)= 0.8680006450950295
# differential_evolution step 520: f(x)= 0.8680006450950295
# differential_evolution step 521: f(x)= 0.8680006450950295
# differential_evolution step 522: f(x)= 0.8680006450950295
# differential_evolution step 523: f(x)= 0.8680006450950295
# differential_evolution step 524: f(x)= 0.8680006450950295
# differential_evolution step 525: f(x)= 0.8680006450950295
# differential_evolution step 526: f(x)= 0.8680006450950295
# differential_evolution step 527: f(x)= 0.8680006450950295
# differential_evolution step 528: f(x)= 0.8680006450950295
# differential_evolution step 529: f(x)= 0.8680006450950295
# differential_evolution step 530: f(x)= 0.8680006450950295
# differential_evolution step 531: f(x)= 0.8680006450950295
# differential_evolution step 532: f(x)= 0.8680006450950295
# differential_evolution step 533: f(x)= 0.8680006450950295
# differential_evolution step 534: f(x)= 0.8680006450950295
# differential_evolution step 535: f(x)= 0.8680006450950295
# differential_evolution step 536: f(x)= 0.8680006450950295
# differential_evolution step 537: f(x)= 0.8680006450950295
# differential_evolution step 538: f(x)= 0.8680006450950295
# differential_evolution step 539: f(x)= 0.8670718434074863
# differential_evolution step 540: f(x)= 0.8670718434074863
# differential_evolution step 541: f(x)= 0.8664586583209096
# differential_evolution step 542: f(x)= 0.8664586583209096
# differential_evolution step 543: f(x)= 0.8664586583209096
# differential_evolution step 544: f(x)= 0.8664586583209096
# differential_evolution step 545: f(x)= 0.8664586583209096
# differential_evolution step 546: f(x)= 0.8664586583209096
# differential_evolution step 547: f(x)= 0.8664586583209096
# differential_evolution step 548: f(x)= 0.8664586583209096
# differential_evolution step 549: f(x)= 0.8664586583209096
# differential_evolution step 550: f(x)= 0.8662404950176019
# differential_evolution step 551: f(x)= 0.8660571130597345
# differential_evolution step 552: f(x)= 0.8660571130597345
# differential_evolution step 553: f(x)= 0.8660571130597345
# differential_evolution step 554: f(x)= 0.8660571130597345
# differential_evolution step 555: f(x)= 0.8660571130597345
# differential_evolution step 556: f(x)= 0.8660571130597345
# differential_evolution step 557: f(x)= 0.8660571130597345
# differential_evolution step 558: f(x)= 0.8660571130597345
# differential_evolution step 559: f(x)= 0.8660571130597345
# differential_evolution step 560: f(x)= 0.8660571130597345
# differential_evolution step 561: f(x)= 0.8660571130597345
# differential_evolution step 562: f(x)= 0.8660571130597345
# differential_evolution step 563: f(x)= 0.8660571130597345
# differential_evolution step 564: f(x)= 0.8660571130597345
# differential_evolution step 565: f(x)= 0.8660571130597345
# differential_evolution step 566: f(x)= 0.8660571130597345
# differential_evolution step 567: f(x)= 0.8660571130597345
# differential_evolution step 568: f(x)= 0.8660571130597345
# differential_evolution step 569: f(x)= 0.8659615087212317
# differential_evolution step 570: f(x)= 0.8658102863289421
# differential_evolution step 571: f(x)= 0.8658102863289421
# differential_evolution step 572: f(x)= 0.8658102863289421
# differential_evolution step 573: f(x)= 0.8658102863289421
# differential_evolution step 574: f(x)= 0.8658102863289421
# differential_evolution step 575: f(x)= 0.8658102863289421
# differential_evolution step 576: f(x)= 0.8658102863289421
# differential_evolution step 577: f(x)= 0.8653846578624366
# differential_evolution step 578: f(x)= 0.8653846578624366
# differential_evolution step 579: f(x)= 0.8653846578624366
# differential_evolution step 580: f(x)= 0.8653846578624366
# differential_evolution step 581: f(x)= 0.8653846578624366
# differential_evolution step 582: f(x)= 0.8653846578624366
# differential_evolution step 583: f(x)= 0.8653846578624366
# differential_evolution step 584: f(x)= 0.8653846578624366
# differential_evolution step 585: f(x)= 0.8653846578624366
# differential_evolution step 586: f(x)= 0.8653846578624366
# differential_evolution step 587: f(x)= 0.8653382007735555
# differential_evolution step 588: f(x)= 0.8647714892888141
# differential_evolution step 589: f(x)= 0.8638622335995128
# differential_evolution step 590: f(x)= 0.8638622335995128
# differential_evolution step 591: f(x)= 0.8638622335995128
# differential_evolution step 592: f(x)= 0.8638622335995128
# differential_evolution step 593: f(x)= 0.8638622335995128
# differential_evolution step 594: f(x)= 0.8638622335995128
# differential_evolution step 595: f(x)= 0.8638622335995128
# differential_evolution step 596: f(x)= 0.8638622335995128
# differential_evolution step 597: f(x)= 0.8638622335995128
# differential_evolution step 598: f(x)= 0.8638622335995128
# differential_evolution step 599: f(x)= 0.8638622335995128
# differential_evolution step 600: f(x)= 0.8638622335995128
# differential_evolution step 601: f(x)= 0.8638234763170379
# differential_evolution step 602: f(x)= 0.863413838220699
# differential_evolution step 603: f(x)= 0.863413838220699
# differential_evolution step 604: f(x)= 0.863413838220699
# differential_evolution step 605: f(x)= 0.863278238303196
# differential_evolution step 606: f(x)= 0.8629241068123515
# differential_evolution step 607: f(x)= 0.8629241068123515
# differential_evolution step 608: f(x)= 0.8629241068123515
# differential_evolution step 609: f(x)= 0.8629241068123515
# differential_evolution step 610: f(x)= 0.8629241068123515
# differential_evolution step 611: f(x)= 0.8629241068123515
# differential_evolution step 612: f(x)= 0.8629241068123515
# differential_evolution step 613: f(x)= 0.8629241068123515
# differential_evolution step 614: f(x)= 0.8629241068123515
# differential_evolution step 615: f(x)= 0.8629241068123515
# differential_evolution step 616: f(x)= 0.8629241068123515
# differential_evolution step 617: f(x)= 0.8629241068123515
# differential_evolution step 618: f(x)= 0.8629241068123515
# differential_evolution step 619: f(x)= 0.8629241068123515
# differential_evolution step 620: f(x)= 0.8629241068123515
# differential_evolution step 621: f(x)= 0.8629241068123515
# differential_evolution step 622: f(x)= 0.8629241068123515
# differential_evolution step 623: f(x)= 0.8629241068123515
# differential_evolution step 624: f(x)= 0.8629241068123515
# differential_evolution step 625: f(x)= 0.8629241068123515
# differential_evolution step 626: f(x)= 0.8629241068123515
# differential_evolution step 627: f(x)= 0.8629241068123515
# differential_evolution step 628: f(x)= 0.8628172847217576
# differential_evolution step 629: f(x)= 0.8628172847217576
# differential_evolution step 630: f(x)= 0.8628172847217576
# differential_evolution step 631: f(x)= 0.8628172847217576
# differential_evolution step 632: f(x)= 0.8628172847217576
# differential_evolution step 633: f(x)= 0.8628172847217576
# differential_evolution step 634: f(x)= 0.8628172847217576
# differential_evolution step 635: f(x)= 0.8628172847217576
# differential_evolution step 636: f(x)= 0.8628172847217576
# differential_evolution step 637: f(x)= 0.8628172847217576
# differential_evolution step 638: f(x)= 0.8628172847217576
# differential_evolution step 639: f(x)= 0.8628172847217576
# differential_evolution step 640: f(x)= 0.8628172847217576
# differential_evolution step 641: f(x)= 0.8628172847217576
# differential_evolution step 642: f(x)= 0.8628172847217576
# differential_evolution step 643: f(x)= 0.8628172847217576
# differential_evolution step 644: f(x)= 0.8628172847217576
# differential_evolution step 645: f(x)= 0.8628172847217576
# differential_evolution step 646: f(x)= 0.8628172847217576
# differential_evolution step 647: f(x)= 0.8628172847217576
# differential_evolution step 648: f(x)= 0.8628172847217576
# differential_evolution step 649: f(x)= 0.8628172847217576
# differential_evolution step 650: f(x)= 0.8628172847217576
# differential_evolution step 651: f(x)= 0.8626419004195166
# differential_evolution step 652: f(x)= 0.8626419004195166
# differential_evolution step 653: f(x)= 0.8626419004195166
# differential_evolution step 654: f(x)= 0.8626419004195166
# differential_evolution step 655: f(x)= 0.8626419004195166
# differential_evolution step 656: f(x)= 0.8626419004195166
# differential_evolution step 657: f(x)= 0.8626419004195166
# differential_evolution step 658: f(x)= 0.8626419004195166
# differential_evolution step 659: f(x)= 0.8626419004195166
# differential_evolution step 660: f(x)= 0.8626419004195166
# differential_evolution step 661: f(x)= 0.8626419004195166
# differential_evolution step 662: f(x)= 0.8626419004195166
# differential_evolution step 663: f(x)= 0.8626419004195166
# differential_evolution step 664: f(x)= 0.8626419004195166
# differential_evolution step 665: f(x)= 0.8626419004195166
# differential_evolution step 666: f(x)= 0.8626419004195166
# differential_evolution step 667: f(x)= 0.8626419004195166
# differential_evolution step 668: f(x)= 0.8626419004195166
# differential_evolution step 669: f(x)= 0.8626419004195166
# differential_evolution step 670: f(x)= 0.8626419004195166
# differential_evolution step 671: f(x)= 0.8626419004195166
# differential_evolution step 672: f(x)= 0.8626419004195166
# differential_evolution step 673: f(x)= 0.8626419004195166
# differential_evolution step 674: f(x)= 0.8626419004195166
# differential_evolution step 675: f(x)= 0.8626419004195166
# differential_evolution step 676: f(x)= 0.8626419004195166
# differential_evolution step 677: f(x)= 0.8626419004195166
# differential_evolution step 678: f(x)= 0.8626419004195166
# differential_evolution step 679: f(x)= 0.8626419004195166
# differential_evolution step 680: f(x)= 0.8626419004195166
# differential_evolution step 681: f(x)= 0.8626419004195166
# differential_evolution step 682: f(x)= 0.8626419004195166
# differential_evolution step 683: f(x)= 0.8626419004195166
# differential_evolution step 684: f(x)= 0.8624794108116273
# differential_evolution step 685: f(x)= 0.8623534168052526
# differential_evolution step 686: f(x)= 0.8623534168052526
# differential_evolution step 687: f(x)= 0.8623534168052526
# differential_evolution step 688: f(x)= 0.8623534168052526
# differential_evolution step 689: f(x)= 0.8623534168052526
# differential_evolution step 690: f(x)= 0.8623534168052526
# differential_evolution step 691: f(x)= 0.8623534168052526
# differential_evolution step 692: f(x)= 0.8623534168052526
# differential_evolution step 693: f(x)= 0.8620962163788006
# differential_evolution step 694: f(x)= 0.8620962163788006
# differential_evolution step 695: f(x)= 0.8620962163788006
# differential_evolution step 696: f(x)= 0.8620962163788006
# differential_evolution step 697: f(x)= 0.8620962163788006
# differential_evolution step 698: f(x)= 0.8620962163788006
# differential_evolution step 699: f(x)= 0.8620962163788006
# differential_evolution step 700: f(x)= 0.8620962163788006
# differential_evolution step 701: f(x)= 0.8620962163788006
# differential_evolution step 702: f(x)= 0.8620962163788006
# differential_evolution step 703: f(x)= 0.8620962163788006
# differential_evolution step 704: f(x)= 0.8620962163788006
# differential_evolution step 705: f(x)= 0.8620962163788006
# differential_evolution step 706: f(x)= 0.8620962163788006
# differential_evolution step 707: f(x)= 0.8620962163788006
# differential_evolution step 708: f(x)= 0.8620962163788006
# differential_evolution step 709: f(x)= 0.8620962163788006
# differential_evolution step 710: f(x)= 0.8620962163788006
# differential_evolution step 711: f(x)= 0.8620625107220318
# differential_evolution step 712: f(x)= 0.8618936635127146
# differential_evolution step 713: f(x)= 0.8618936635127146
# differential_evolution step 714: f(x)= 0.8618936635127146
# differential_evolution step 715: f(x)= 0.8618936635127146
# differential_evolution step 716: f(x)= 0.8618936635127146
# differential_evolution step 717: f(x)= 0.8618936635127146
# differential_evolution step 718: f(x)= 0.8617273951559652
# differential_evolution step 719: f(x)= 0.8617273951559652
# differential_evolution step 720: f(x)= 0.8617273951559652
# differential_evolution step 721: f(x)= 0.8617273951559652
# differential_evolution step 722: f(x)= 0.8617273951559652
# differential_evolution step 723: f(x)= 0.8617273951559652
# differential_evolution step 724: f(x)= 0.8617273951559652
# differential_evolution step 725: f(x)= 0.8617273951559652
# differential_evolution step 726: f(x)= 0.8616382425629681
# differential_evolution step 727: f(x)= 0.8616382425629681
# differential_evolution step 728: f(x)= 0.8616382425629681
# differential_evolution step 729: f(x)= 0.8616382425629681
# differential_evolution step 730: f(x)= 0.8616303038937104
# differential_evolution step 731: f(x)= 0.8616303038937104
# differential_evolution step 732: f(x)= 0.8616303038937104
# differential_evolution step 733: f(x)= 0.8615339654470638
# differential_evolution step 734: f(x)= 0.8615339654470638
# differential_evolution step 735: f(x)= 0.8615339654470638
# differential_evolution step 736: f(x)= 0.8615339654470638
# differential_evolution step 737: f(x)= 0.8614914894404063
# differential_evolution step 738: f(x)= 0.8614914894404063
# differential_evolution step 739: f(x)= 0.8614914894404063
# differential_evolution step 740: f(x)= 0.8614914894404063
# differential_evolution step 741: f(x)= 0.8614914894404063
# differential_evolution step 742: f(x)= 0.8614914894404063
# differential_evolution step 743: f(x)= 0.8614800093121321
# differential_evolution step 744: f(x)= 0.8614800093121321
# differential_evolution step 745: f(x)= 0.8614800093121321
# differential_evolution step 746: f(x)= 0.8614800093121321
# differential_evolution step 747: f(x)= 0.8614800093121321
# differential_evolution step 748: f(x)= 0.8614800093121321
# differential_evolution step 749: f(x)= 0.8614800093121321
# differential_evolution step 750: f(x)= 0.8614800093121321
# differential_evolution step 751: f(x)= 0.8614800093121321
# differential_evolution step 752: f(x)= 0.8614800093121321
# differential_evolution step 753: f(x)= 0.8614800093121321
# differential_evolution step 754: f(x)= 0.8614800093121321
# differential_evolution step 755: f(x)= 0.8614800093121321
# differential_evolution step 756: f(x)= 0.8614800093121321
# differential_evolution step 757: f(x)= 0.8614800093121321
# differential_evolution step 758: f(x)= 0.8614800093121321
# differential_evolution step 759: f(x)= 0.8614800093121321
# differential_evolution step 760: f(x)= 0.8614800093121321
# differential_evolution step 761: f(x)= 0.8614511285952887
# differential_evolution step 762: f(x)= 0.8614511285952887
# differential_evolution step 763: f(x)= 0.8614511285952887
# differential_evolution step 764: f(x)= 0.8614511285952887
# differential_evolution step 765: f(x)= 0.8614511285952887
# differential_evolution step 766: f(x)= 0.8614084778720965
# differential_evolution step 767: f(x)= 0.8614084778720965
# differential_evolution step 768: f(x)= 0.8614084778720965
# differential_evolution step 769: f(x)= 0.8614084778720965
# differential_evolution step 770: f(x)= 0.8614084778720965
# differential_evolution step 771: f(x)= 0.8614084778720965
# differential_evolution step 772: f(x)= 0.8614084778720965
# differential_evolution step 773: f(x)= 0.8614084778720965
# differential_evolution step 774: f(x)= 0.8614084778720965
# differential_evolution step 775: f(x)= 0.8613971086854051
# differential_evolution step 776: f(x)= 0.8613177266039883
# differential_evolution step 777: f(x)= 0.8613177266039883
# differential_evolution step 778: f(x)= 0.8613177266039883
# differential_evolution step 779: f(x)= 0.8613177266039883
# differential_evolution step 780: f(x)= 0.8613177266039883
# differential_evolution step 781: f(x)= 0.8613177266039883
# differential_evolution step 782: f(x)= 0.8613177266039883
# differential_evolution step 783: f(x)= 0.8613177266039883
# differential_evolution step 784: f(x)= 0.8613177266039883
# differential_evolution step 785: f(x)= 0.8613177266039883
# differential_evolution step 786: f(x)= 0.8613177266039883
# differential_evolution step 787: f(x)= 0.8613177266039883
# differential_evolution step 788: f(x)= 0.8613177266039883
# differential_evolution step 789: f(x)= 0.8613177266039883
# differential_evolution step 790: f(x)= 0.8613177266039883
# differential_evolution step 791: f(x)= 0.8613177266039883
# differential_evolution step 792: f(x)= 0.8613177266039883
# differential_evolution step 793: f(x)= 0.8613177266039883
# differential_evolution step 794: f(x)= 0.8613177266039883
# differential_evolution step 795: f(x)= 0.8613177266039883
# differential_evolution step 796: f(x)= 0.8613177266039883
# differential_evolution step 797: f(x)= 0.8613177266039883
# differential_evolution step 798: f(x)= 0.8613177266039883
# differential_evolution step 799: f(x)= 0.8613177266039883
# differential_evolution step 800: f(x)= 0.8613177266039883
# differential_evolution step 801: f(x)= 0.8613177266039883
# differential_evolution step 802: f(x)= 0.8613177266039883
# differential_evolution step 803: f(x)= 0.8613177266039883
# differential_evolution step 804: f(x)= 0.8613177266039883
# differential_evolution step 805: f(x)= 0.8613177266039883
# differential_evolution step 806: f(x)= 0.8613177266039883
# differential_evolution step 807: f(x)= 0.8613177266039883
# differential_evolution step 808: f(x)= 0.8613177266039883
# differential_evolution step 809: f(x)= 0.8613177266039883
# differential_evolution step 810: f(x)= 0.8613177266039883
# differential_evolution step 811: f(x)= 0.8613177266039883
# differential_evolution step 812: f(x)= 0.8613177266039883
# differential_evolution step 813: f(x)= 0.8613177266039883
# differential_evolution step 814: f(x)= 0.8613177266039883
# differential_evolution step 815: f(x)= 0.8613177266039883
# differential_evolution step 816: f(x)= 0.8612902117992824
# differential_evolution step 817: f(x)= 0.8612902117992824
# differential_evolution step 818: f(x)= 0.8612902117992824
# differential_evolution step 819: f(x)= 0.8612902117992824
# differential_evolution step 820: f(x)= 0.8612902117992824
# differential_evolution step 821: f(x)= 0.8612902117992824
# differential_evolution step 822: f(x)= 0.8612902117992824
# differential_evolution step 823: f(x)= 0.8612894176944994
# differential_evolution step 824: f(x)= 0.8612894176944994
# differential_evolution step 825: f(x)= 0.8612894176944994
# differential_evolution step 826: f(x)= 0.8612894176944994
# differential_evolution step 827: f(x)= 0.8612894176944994
# differential_evolution step 828: f(x)= 0.8612894176944994
# differential_evolution step 829: f(x)= 0.8612894176944994
# differential_evolution step 830: f(x)= 0.8612894176944994
# differential_evolution step 831: f(x)= 0.8612894176944994
# differential_evolution step 832: f(x)= 0.8612894176944994
# differential_evolution step 833: f(x)= 0.8612894176944994
# differential_evolution step 834: f(x)= 0.8612894176944994
# differential_evolution step 835: f(x)= 0.8612894176944994
# differential_evolution step 836: f(x)= 0.8612894176944994
# differential_evolution step 837: f(x)= 0.8612863818832008
# differential_evolution step 838: f(x)= 0.8612863818832008
# differential_evolution step 839: f(x)= 0.8612863818832008
# differential_evolution step 840: f(x)= 0.8612863818832008
# differential_evolution step 841: f(x)= 0.8612863818832008
# differential_evolution step 842: f(x)= 0.8612683163267149
# differential_evolution step 843: f(x)= 0.8612683163267149
# differential_evolution step 844: f(x)= 0.8612683163267149
# differential_evolution step 845: f(x)= 0.8612683163267149
# differential_evolution step 846: f(x)= 0.8612683163267149
# differential_evolution step 847: f(x)= 0.8612683163267149
# differential_evolution step 848: f(x)= 0.8612683163267149
# differential_evolution step 849: f(x)= 0.8612683163267149
# differential_evolution step 850: f(x)= 0.8612683163267149
# differential_evolution step 851: f(x)= 0.8612683163267149
# differential_evolution step 852: f(x)= 0.8612683163267149
# differential_evolution step 853: f(x)= 0.8612683163267149
# differential_evolution step 854: f(x)= 0.8612683163267149
# differential_evolution step 855: f(x)= 0.8612591343288336
# differential_evolution step 856: f(x)= 0.8612591343288336
# differential_evolution step 857: f(x)= 0.8612591343288336
# differential_evolution step 858: f(x)= 0.8612591343288336
# differential_evolution step 859: f(x)= 0.8612591343288336
# differential_evolution step 860: f(x)= 0.8612591343288336
# differential_evolution step 861: f(x)= 0.8612591343288336
# differential_evolution step 862: f(x)= 0.8612591343288336
# differential_evolution step 863: f(x)= 0.8612591343288336
# differential_evolution step 864: f(x)= 0.8612591343288336
# differential_evolution step 865: f(x)= 0.8612591343288336
# differential_evolution step 866: f(x)= 0.8612591343288336
# differential_evolution step 867: f(x)= 0.8612591343288336
# differential_evolution step 868: f(x)= 0.8612591343288336
# differential_evolution step 869: f(x)= 0.8612591343288336
# differential_evolution step 870: f(x)= 0.8612591343288336
# differential_evolution step 871: f(x)= 0.8612591343288336
# differential_evolution step 872: f(x)= 0.8612591343288336
# differential_evolution step 873: f(x)= 0.8612591343288336
# differential_evolution step 874: f(x)= 0.8612591343288336
# differential_evolution step 875: f(x)= 0.8612591343288336
# differential_evolution step 876: f(x)= 0.8612591343288336
# differential_evolution step 877: f(x)= 0.8612591343288336
# differential_evolution step 878: f(x)= 0.8612591343288336
# differential_evolution step 879: f(x)= 0.8612557865058291
# differential_evolution step 880: f(x)= 0.8612519039581207
# differential_evolution step 881: f(x)= 0.8612496461330933
# differential_evolution step 882: f(x)= 0.8612496461330933
# differential_evolution step 883: f(x)= 0.8612496461330933
# differential_evolution step 884: f(x)= 0.8612496461330933
# differential_evolution step 885: f(x)= 0.8612496461330933
# differential_evolution step 886: f(x)= 0.8612453063851222
# differential_evolution step 887: f(x)= 0.8612453063851222
# differential_evolution step 888: f(x)= 0.8612453063851222
# differential_evolution step 889: f(x)= 0.8612453063851222
# differential_evolution step 890: f(x)= 0.8612453063851222
# differential_evolution step 891: f(x)= 0.8612453063851222
# differential_evolution step 892: f(x)= 0.8612453063851222
# differential_evolution step 893: f(x)= 0.8612453063851222
# differential_evolution step 894: f(x)= 0.8612453063851222
# differential_evolution step 895: f(x)= 0.8612453063851222
# differential_evolution step 896: f(x)= 0.8612453063851222
# differential_evolution step 897: f(x)= 0.8612453063851222
# differential_evolution step 898: f(x)= 0.8612453063851222
# differential_evolution step 899: f(x)= 0.8612453063851222
# differential_evolution step 900: f(x)= 0.8612432194307017
# differential_evolution step 901: f(x)= 0.8612432194307017
# differential_evolution step 902: f(x)= 0.8612432194307017
# differential_evolution step 903: f(x)= 0.8612432194307017
# differential_evolution step 904: f(x)= 0.8612432194307017
# differential_evolution step 905: f(x)= 0.861239624483982
# differential_evolution step 906: f(x)= 0.861239624483982
# differential_evolution step 907: f(x)= 0.861239624483982
# differential_evolution step 908: f(x)= 0.861239624483982
# differential_evolution step 909: f(x)= 0.861239624483982
# differential_evolution step 910: f(x)= 0.861239624483982
# differential_evolution step 911: f(x)= 0.861239624483982
# differential_evolution step 912: f(x)= 0.8612313502108678
# differential_evolution step 913: f(x)= 0.8612313502108678
# differential_evolution step 914: f(x)= 0.8612313502108678
# differential_evolution step 915: f(x)= 0.8612313502108678
# differential_evolution step 916: f(x)= 0.8612313502108678
# differential_evolution step 917: f(x)= 0.8612313502108678
# differential_evolution step 918: f(x)= 0.8612313502108678
# differential_evolution step 919: f(x)= 0.8612313502108678
# differential_evolution step 920: f(x)= 0.8612313502108678
# differential_evolution step 921: f(x)= 0.8612313502108678
# differential_evolution step 922: f(x)= 0.8612313502108678
# differential_evolution step 923: f(x)= 0.8612313502108678
# differential_evolution step 924: f(x)= 0.8612313502108678
# differential_evolution step 925: f(x)= 0.8612313502108678
# differential_evolution step 926: f(x)= 0.8612313502108678
# differential_evolution step 927: f(x)= 0.8612313502108678
# differential_evolution step 928: f(x)= 0.8612313502108678
# differential_evolution step 929: f(x)= 0.8612313502108678
# differential_evolution step 930: f(x)= 0.8612313502108678
# differential_evolution step 931: f(x)= 0.8612313502108678
# differential_evolution step 932: f(x)= 0.8612313502108678
# differential_evolution step 933: f(x)= 0.8612313502108678
# differential_evolution step 934: f(x)= 0.8612313502108678
# differential_evolution step 935: f(x)= 0.8612313502108678
# differential_evolution step 936: f(x)= 0.8612313502108678
# differential_evolution step 937: f(x)= 0.8612313502108678
# differential_evolution step 938: f(x)= 0.8612313502108678
# differential_evolution step 939: f(x)= 0.8612313502108678
# differential_evolution step 940: f(x)= 0.8612313502108678
# differential_evolution step 941: f(x)= 0.8612313502108678
# differential_evolution step 942: f(x)= 0.8612313502108678
# differential_evolution step 943: f(x)= 0.8612313502108678
# differential_evolution step 944: f(x)= 0.8612313502108678
# differential_evolution step 945: f(x)= 0.8612313502108678
# differential_evolution step 946: f(x)= 0.8612313502108678
# differential_evolution step 947: f(x)= 0.8612313502108678
# differential_evolution step 948: f(x)= 0.8612313502108678
# differential_evolution step 949: f(x)= 0.8612313502108678
# differential_evolution step 950: f(x)= 0.8612313502108678
# differential_evolution step 951: f(x)= 0.8612313502108678
# differential_evolution step 952: f(x)= 0.8612313502108678
# differential_evolution step 953: f(x)= 0.8612313502108678
# differential_evolution step 954: f(x)= 0.8612288626771067
# differential_evolution step 955: f(x)= 0.8612288626771067
# differential_evolution step 956: f(x)= 0.8612282195527688
# differential_evolution step 957: f(x)= 0.8612282195527688
# differential_evolution step 958: f(x)= 0.8612282195527688
# differential_evolution step 959: f(x)= 0.8612282195527688
# differential_evolution step 960: f(x)= 0.8612282195527688
# differential_evolution step 961: f(x)= 0.8612282195527688
# differential_evolution step 962: f(x)= 0.8612282195527688
# differential_evolution step 963: f(x)= 0.8612282195527688
# differential_evolution step 964: f(x)= 0.8612282195527688
# differential_evolution step 965: f(x)= 0.8612282195527688
# differential_evolution step 966: f(x)= 0.8612282195527688
# differential_evolution step 967: f(x)= 0.8612282195527688
# differential_evolution step 968: f(x)= 0.8612282195527688
# differential_evolution step 969: f(x)= 0.8612282195527688
# differential_evolution step 970: f(x)= 0.8612282195527688
# differential_evolution step 971: f(x)= 0.8612282195527688
# differential_evolution step 972: f(x)= 0.8612282195527688
# differential_evolution step 973: f(x)= 0.8612282195527688
# differential_evolution step 974: f(x)= 0.8612282195527688
# differential_evolution step 975: f(x)= 0.8612282195527688
# differential_evolution step 976: f(x)= 0.8612282195527688
# differential_evolution step 977: f(x)= 0.8612282195527688
# differential_evolution step 978: f(x)= 0.8612256601481206
# differential_evolution step 979: f(x)= 0.8612256601481206
# differential_evolution step 980: f(x)= 0.8612256601481206
# differential_evolution step 981: f(x)= 0.8612256601481206
# differential_evolution step 982: f(x)= 0.8612256601481206
# differential_evolution step 983: f(x)= 0.8612236350236171
# differential_evolution step 984: f(x)= 0.8612236350236171
# differential_evolution step 985: f(x)= 0.8612236350236171
# differential_evolution step 986: f(x)= 0.8612236350236171
# differential_evolution step 987: f(x)= 0.8612236350236171
# differential_evolution step 988: f(x)= 0.8612236350236171
# differential_evolution step 989: f(x)= 0.8612236350236171
# differential_evolution step 990: f(x)= 0.8612236350236171
# differential_evolution step 991: f(x)= 0.8612236350236171
# differential_evolution step 992: f(x)= 0.8612236350236171
# differential_evolution step 993: f(x)= 0.8612236350236171
# differential_evolution step 994: f(x)= 0.8612236350236171
# differential_evolution step 995: f(x)= 0.8612236350236171
# differential_evolution step 996: f(x)= 0.8612236350236171
# differential_evolution step 997: f(x)= 0.8612236350236171
# differential_evolution step 998: f(x)= 0.8612236350236171
# differential_evolution step 999: f(x)= 0.8612236350236171
# differential_evolution step 1000: f(x)= 0.8612236350236171
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.9606, r_e=7.6941, n=1.0563, x_0=44.9260
# Sérsic 2: I_e=0.2254, r_e=36.0560, n=1.7453, x_0=51.4090
# Sérsic 3: I_e=2.2854, r_e=5.2495, n=0.5343, x_0=60.3699
# Chi quadro minimo: 0.8612113251503819
# False

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=0.9606, r_e=7.6941, n=1.0563, x_0=44.9260
# Sérsic 2: I_e=0.2254, r_e=36.0560, n=1.7453, x_0=51.4090
# Sérsic 3: I_e=2.2854, r_e=5.2495, n=0.5343, x_0=60.3699
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Diff_params/SII_fit_diff.csv", index_col=0)
initial_guesses = np.concatenate([
    df['Component 1'].values,  # [I_e, r_e, n, x_0] per Component 1
    df['Component 2'].values,  # [I_e, r_e, n, x_0] per Component 2
    df['Component 3'].values   # [I_e, r_e, n, x_0] per Component 3
])
print(df)
bounds = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 60),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (38, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 5),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 5),
    (60, 80),
    (0.1, 10),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2),
]
# Out:
#      Component 1  Component 2  Component 3
# I_e       0.2112       1.7787       0.0351
# r_e      49.9998       1.5909      69.9992
# n         2.4882       0.5902       2.7335
# x_0      38.5023      48.5999      80.8042

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=initial_guesses, sigma = real_errors_SII, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2067, r_e=48.0544, n=2.4604, x_0=38.1493
# Sérsic 2: I_e=0.3992, r_e=5.0000, n=1.5959, x_0=48.8064
# Sérsic 3: I_e=0.0403, r_e=60.0030, n=2.6390, x_0=80.5560
# [1.09597197e-01 1.92061488e+01 4.36936201e-01 1.48761401e-01
#  4.13831219e-01 3.53577326e+00 8.13601711e-01 2.26034799e-01
#  7.75878319e-02 9.89262578e+01 1.36744461e+00 2.18065718e-01]
# 8.921088083139246

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[1])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2883.9849849336542
# differential_evolution step 2: f(x)= 2883.9849849336542
# differential_evolution step 3: f(x)= 2811.4148148815707
# differential_evolution step 4: f(x)= 2811.4148148815707
# differential_evolution step 5: f(x)= 1801.5028465082116
# differential_evolution step 6: f(x)= 1801.5028465082116
# differential_evolution step 7: f(x)= 1801.5028465082116
# differential_evolution step 8: f(x)= 1801.5028465082116
# differential_evolution step 9: f(x)= 906.6664129829114
# differential_evolution step 10: f(x)= 906.6664129829114
# differential_evolution step 11: f(x)= 906.6664129829114
# differential_evolution step 12: f(x)= 608.3662986718261
# differential_evolution step 13: f(x)= 608.3662986718261
# differential_evolution step 14: f(x)= 608.3662986718261
# differential_evolution step 15: f(x)= 608.3662986718261
# differential_evolution step 16: f(x)= 608.3662986718261
# differential_evolution step 17: f(x)= 598.6044019867248
# differential_evolution step 18: f(x)= 598.6044019867248
# differential_evolution step 19: f(x)= 598.6044019867248
# differential_evolution step 20: f(x)= 598.6044019867248
# differential_evolution step 21: f(x)= 598.6044019867248
# differential_evolution step 22: f(x)= 362.0767092401903
# differential_evolution step 23: f(x)= 362.0767092401903
# differential_evolution step 24: f(x)= 362.0767092401903
# differential_evolution step 25: f(x)= 362.0767092401903
# differential_evolution step 26: f(x)= 235.56599609394948
# differential_evolution step 27: f(x)= 235.56599609394948
# differential_evolution step 28: f(x)= 235.56599609394948
# differential_evolution step 29: f(x)= 235.56599609394948
# differential_evolution step 30: f(x)= 235.56599609394948
# differential_evolution step 31: f(x)= 235.56599609394948
# differential_evolution step 32: f(x)= 235.56599609394948
# differential_evolution step 33: f(x)= 235.56599609394948
# differential_evolution step 34: f(x)= 235.56599609394948
# differential_evolution step 35: f(x)= 235.56599609394948
# differential_evolution step 36: f(x)= 220.6809549489135
# differential_evolution step 37: f(x)= 220.6809549489135
# differential_evolution step 38: f(x)= 220.6809549489135
# differential_evolution step 39: f(x)= 220.6809549489135
# differential_evolution step 40: f(x)= 187.76910608061658
# differential_evolution step 41: f(x)= 187.76910608061658
# differential_evolution step 42: f(x)= 148.41986801399574
# differential_evolution step 43: f(x)= 148.41986801399574
# differential_evolution step 44: f(x)= 148.41986801399574
# differential_evolution step 45: f(x)= 148.41986801399574
# differential_evolution step 46: f(x)= 148.41986801399574
# differential_evolution step 47: f(x)= 148.41986801399574
# differential_evolution step 48: f(x)= 148.41986801399574
# differential_evolution step 49: f(x)= 148.41986801399574
# differential_evolution step 50: f(x)= 148.41986801399574
# differential_evolution step 51: f(x)= 148.41986801399574
# differential_evolution step 52: f(x)= 148.41986801399574
# differential_evolution step 53: f(x)= 148.41986801399574
# differential_evolution step 54: f(x)= 148.41986801399574
# differential_evolution step 55: f(x)= 148.41986801399574
# differential_evolution step 56: f(x)= 148.41986801399574
# differential_evolution step 57: f(x)= 148.41986801399574
# differential_evolution step 58: f(x)= 148.41986801399574
# differential_evolution step 59: f(x)= 148.41986801399574
# differential_evolution step 60: f(x)= 148.41986801399574
# differential_evolution step 61: f(x)= 129.37793438528018
# differential_evolution step 62: f(x)= 129.37793438528018
# differential_evolution step 63: f(x)= 129.37793438528018
# differential_evolution step 64: f(x)= 129.37793438528018
# differential_evolution step 65: f(x)= 129.37793438528018
# differential_evolution step 66: f(x)= 129.37793438528018
# differential_evolution step 67: f(x)= 129.37793438528018
# differential_evolution step 68: f(x)= 129.37793438528018
# differential_evolution step 69: f(x)= 129.37793438528018
# differential_evolution step 70: f(x)= 129.37793438528018
# differential_evolution step 71: f(x)= 129.37793438528018
# differential_evolution step 72: f(x)= 129.37793438528018
# differential_evolution step 73: f(x)= 129.37793438528018
# differential_evolution step 74: f(x)= 129.37793438528018
# differential_evolution step 75: f(x)= 129.37793438528018
# differential_evolution step 76: f(x)= 129.37793438528018
# differential_evolution step 77: f(x)= 129.37793438528018
# differential_evolution step 78: f(x)= 128.92634689810035
# differential_evolution step 79: f(x)= 127.53580146758213
# differential_evolution step 80: f(x)= 117.69592649253532
# differential_evolution step 81: f(x)= 116.82237043891236
# differential_evolution step 82: f(x)= 116.82237043891236
# differential_evolution step 83: f(x)= 116.82237043891236
# differential_evolution step 84: f(x)= 116.82237043891236
# differential_evolution step 85: f(x)= 116.82237043891236
# differential_evolution step 86: f(x)= 116.82237043891236
# differential_evolution step 87: f(x)= 116.82237043891236
# differential_evolution step 88: f(x)= 115.03269767686785
# differential_evolution step 89: f(x)= 114.67718644944605
# differential_evolution step 90: f(x)= 114.67718644944605
# differential_evolution step 91: f(x)= 114.67718644944605
# differential_evolution step 92: f(x)= 112.79332416332822
# differential_evolution step 93: f(x)= 112.79332416332822
# differential_evolution step 94: f(x)= 112.79332416332822
# differential_evolution step 95: f(x)= 112.79332416332822
# differential_evolution step 96: f(x)= 111.66569389780649
# differential_evolution step 97: f(x)= 111.66569389780649
# differential_evolution step 98: f(x)= 111.50305385069673
# differential_evolution step 99: f(x)= 105.74043199860033
# differential_evolution step 100: f(x)= 105.74043199860033
# differential_evolution step 101: f(x)= 105.74043199860033
# differential_evolution step 102: f(x)= 105.74043199860033
# differential_evolution step 103: f(x)= 105.74043199860033
# differential_evolution step 104: f(x)= 104.727478942899
# differential_evolution step 105: f(x)= 104.727478942899
# differential_evolution step 106: f(x)= 101.79032434262372
# differential_evolution step 107: f(x)= 101.79032434262372
# differential_evolution step 108: f(x)= 101.347054132253
# differential_evolution step 109: f(x)= 101.347054132253
# differential_evolution step 110: f(x)= 101.347054132253
# differential_evolution step 111: f(x)= 101.347054132253
# differential_evolution step 112: f(x)= 101.347054132253
# differential_evolution step 113: f(x)= 101.347054132253
# differential_evolution step 114: f(x)= 101.347054132253
# differential_evolution step 115: f(x)= 101.347054132253
# differential_evolution step 116: f(x)= 101.347054132253
# differential_evolution step 117: f(x)= 100.73399627757078
# differential_evolution step 118: f(x)= 98.14241500280025
# differential_evolution step 119: f(x)= 98.14241500280025
# differential_evolution step 120: f(x)= 98.14241500280025
# differential_evolution step 121: f(x)= 98.14241500280025
# differential_evolution step 122: f(x)= 96.39911771812093
# differential_evolution step 123: f(x)= 96.39911771812093
# differential_evolution step 124: f(x)= 96.39911771812093
# differential_evolution step 125: f(x)= 96.39911771812093
# differential_evolution step 126: f(x)= 96.39911771812093
# differential_evolution step 127: f(x)= 96.39911771812093
# differential_evolution step 128: f(x)= 96.39911771812093
# differential_evolution step 129: f(x)= 96.39911771812093
# differential_evolution step 130: f(x)= 96.39911771812093
# differential_evolution step 131: f(x)= 96.39911771812093
# differential_evolution step 132: f(x)= 96.39911771812093
# differential_evolution step 133: f(x)= 96.39911771812093
# differential_evolution step 134: f(x)= 96.39911771812093
# differential_evolution step 135: f(x)= 96.39911771812093
# differential_evolution step 136: f(x)= 96.39911771812093
# differential_evolution step 137: f(x)= 96.39911771812093
# differential_evolution step 138: f(x)= 96.39911771812093
# differential_evolution step 139: f(x)= 96.39911771812093
# differential_evolution step 140: f(x)= 96.39911771812093
# differential_evolution step 141: f(x)= 96.39911771812093
# differential_evolution step 142: f(x)= 96.39911771812093
# differential_evolution step 143: f(x)= 96.39911771812093
# differential_evolution step 144: f(x)= 96.39911771812093
# differential_evolution step 145: f(x)= 96.07117192750516
# differential_evolution step 146: f(x)= 96.07117192750516
# differential_evolution step 147: f(x)= 94.79201756533367
# differential_evolution step 148: f(x)= 94.79201756533367
# differential_evolution step 149: f(x)= 94.79201756533367
# differential_evolution step 150: f(x)= 94.59719880293058
# differential_evolution step 151: f(x)= 94.59719880293058
# differential_evolution step 152: f(x)= 93.04837105050444
# differential_evolution step 153: f(x)= 93.04837105050444
# differential_evolution step 154: f(x)= 93.04837105050444
# differential_evolution step 155: f(x)= 93.04837105050444
# differential_evolution step 156: f(x)= 93.04837105050444
# differential_evolution step 157: f(x)= 93.04837105050444
# differential_evolution step 158: f(x)= 93.04837105050444
# differential_evolution step 159: f(x)= 93.04837105050444
# differential_evolution step 160: f(x)= 93.04837105050444
# differential_evolution step 161: f(x)= 93.04837105050444
# differential_evolution step 162: f(x)= 93.04837105050444
# differential_evolution step 163: f(x)= 93.04837105050444
# differential_evolution step 164: f(x)= 93.04837105050444
# differential_evolution step 165: f(x)= 93.04837105050444
# differential_evolution step 166: f(x)= 93.04837105050444
# differential_evolution step 167: f(x)= 93.04837105050444
# differential_evolution step 168: f(x)= 93.04837105050444
# differential_evolution step 169: f(x)= 93.04837105050444
# differential_evolution step 170: f(x)= 92.88024880390252
# differential_evolution step 171: f(x)= 92.36888336527296
# differential_evolution step 172: f(x)= 92.36888336527296
# differential_evolution step 173: f(x)= 92.36888336527296
# differential_evolution step 174: f(x)= 92.36888336527296
# differential_evolution step 175: f(x)= 92.36888336527296
# differential_evolution step 176: f(x)= 92.36888336527296
# differential_evolution step 177: f(x)= 92.36888336527296
# differential_evolution step 178: f(x)= 92.36888336527296
# differential_evolution step 179: f(x)= 92.36888336527296
# differential_evolution step 180: f(x)= 92.36888336527296
# differential_evolution step 181: f(x)= 92.36888336527296
# differential_evolution step 182: f(x)= 92.36888336527296
# differential_evolution step 183: f(x)= 92.36888336527296
# differential_evolution step 184: f(x)= 92.36888336527296
# differential_evolution step 185: f(x)= 92.36888336527296
# differential_evolution step 186: f(x)= 92.36888336527296
# differential_evolution step 187: f(x)= 92.36888336527296
# differential_evolution step 188: f(x)= 92.36888336527296
# differential_evolution step 189: f(x)= 92.36888336527296
# differential_evolution step 190: f(x)= 92.36888336527296
# differential_evolution step 191: f(x)= 92.26652731553334
# differential_evolution step 192: f(x)= 92.26652731553334
# differential_evolution step 193: f(x)= 92.26652731553334
# differential_evolution step 194: f(x)= 92.26652731553334
# differential_evolution step 195: f(x)= 92.26652731553334
# differential_evolution step 196: f(x)= 92.26652731553334
# differential_evolution step 197: f(x)= 92.26652731553334
# differential_evolution step 198: f(x)= 92.26652731553334
# differential_evolution step 199: f(x)= 92.26652731553334
# differential_evolution step 200: f(x)= 92.26652731553334
# differential_evolution step 201: f(x)= 92.26652731553334
# differential_evolution step 202: f(x)= 92.26652731553334
# differential_evolution step 203: f(x)= 92.26652731553334
# differential_evolution step 204: f(x)= 92.26652731553334
# differential_evolution step 205: f(x)= 92.26652731553334
# differential_evolution step 206: f(x)= 92.26652731553334
# differential_evolution step 207: f(x)= 91.90257800850426
# differential_evolution step 208: f(x)= 91.90257800850426
# differential_evolution step 209: f(x)= 91.43977066227362
# differential_evolution step 210: f(x)= 91.43977066227362
# differential_evolution step 211: f(x)= 91.43977066227362
# differential_evolution step 212: f(x)= 91.03048101345159
# differential_evolution step 213: f(x)= 91.03048101345159
# differential_evolution step 214: f(x)= 91.03048101345159
# differential_evolution step 215: f(x)= 91.03048101345159
# differential_evolution step 216: f(x)= 91.03048101345159
# differential_evolution step 217: f(x)= 91.03048101345159
# differential_evolution step 218: f(x)= 91.03048101345159
# differential_evolution step 219: f(x)= 91.03048101345159
# differential_evolution step 220: f(x)= 91.03048101345159
# differential_evolution step 221: f(x)= 91.03048101345159
# differential_evolution step 222: f(x)= 91.03048101345159
# differential_evolution step 223: f(x)= 91.03048101345159
# differential_evolution step 224: f(x)= 91.03048101345159
# differential_evolution step 225: f(x)= 91.03048101345159
# differential_evolution step 226: f(x)= 91.03048101345159
# differential_evolution step 227: f(x)= 91.03048101345159
# differential_evolution step 228: f(x)= 91.03048101345159
# differential_evolution step 229: f(x)= 91.03048101345159
# differential_evolution step 230: f(x)= 90.80133817997947
# differential_evolution step 231: f(x)= 90.80133817997947
# differential_evolution step 232: f(x)= 90.07346729120822
# differential_evolution step 233: f(x)= 90.07346729120822
# differential_evolution step 234: f(x)= 90.07346729120822
# differential_evolution step 235: f(x)= 89.98759062869392
# differential_evolution step 236: f(x)= 89.93216129220437
# differential_evolution step 237: f(x)= 89.93216129220437
# differential_evolution step 238: f(x)= 89.93216129220437
# differential_evolution step 239: f(x)= 89.92322208193214
# differential_evolution step 240: f(x)= 89.92322208193214
# differential_evolution step 241: f(x)= 89.92322208193214
# differential_evolution step 242: f(x)= 89.82828364735211
# differential_evolution step 243: f(x)= 89.82828364735211
# differential_evolution step 244: f(x)= 89.82828364735211
# differential_evolution step 245: f(x)= 89.82828364735211
# differential_evolution step 246: f(x)= 89.82828364735211
# differential_evolution step 247: f(x)= 89.82828364735211
# differential_evolution step 248: f(x)= 89.82828364735211
# differential_evolution step 249: f(x)= 89.82828364735211
# differential_evolution step 250: f(x)= 89.82828364735211
# differential_evolution step 251: f(x)= 89.82828364735211
# differential_evolution step 252: f(x)= 89.82828364735211
# differential_evolution step 253: f(x)= 89.82828364735211
# differential_evolution step 254: f(x)= 89.82828364735211
# differential_evolution step 255: f(x)= 89.82828364735211
# differential_evolution step 256: f(x)= 89.82828364735211
# differential_evolution step 257: f(x)= 89.70149786488089
# differential_evolution step 258: f(x)= 89.69162968202976
# differential_evolution step 259: f(x)= 88.84092836716859
# differential_evolution step 260: f(x)= 88.84092836716859
# differential_evolution step 261: f(x)= 88.84092836716859
# differential_evolution step 262: f(x)= 88.84092836716859
# differential_evolution step 263: f(x)= 88.84092836716859
# differential_evolution step 264: f(x)= 88.84092836716859
# differential_evolution step 265: f(x)= 88.84092836716859
# differential_evolution step 266: f(x)= 88.84092836716859
# differential_evolution step 267: f(x)= 88.84092836716859
# differential_evolution step 268: f(x)= 88.84092836716859
# differential_evolution step 269: f(x)= 88.84092836716859
# differential_evolution step 270: f(x)= 88.84092836716859
# differential_evolution step 271: f(x)= 88.84092836716859
# differential_evolution step 272: f(x)= 88.84092836716859
# differential_evolution step 273: f(x)= 88.84092836716859
# differential_evolution step 274: f(x)= 88.84092836716859
# differential_evolution step 275: f(x)= 88.84092836716859
# differential_evolution step 276: f(x)= 88.84092836716859
# differential_evolution step 277: f(x)= 88.84092836716859
# differential_evolution step 278: f(x)= 88.84092836716859
# differential_evolution step 279: f(x)= 88.84092836716859
# differential_evolution step 280: f(x)= 88.84092836716859
# differential_evolution step 281: f(x)= 88.84092836716859
# differential_evolution step 282: f(x)= 88.84092836716859
# differential_evolution step 283: f(x)= 88.84092836716859
# differential_evolution step 284: f(x)= 88.84092836716859
# differential_evolution step 285: f(x)= 88.84092836716859
# differential_evolution step 286: f(x)= 88.84092836716859
# differential_evolution step 287: f(x)= 88.84092836716859
# differential_evolution step 288: f(x)= 88.84092836716859
# differential_evolution step 289: f(x)= 88.84092836716859
# differential_evolution step 290: f(x)= 88.84092836716859
# differential_evolution step 291: f(x)= 88.84092836716859
# differential_evolution step 292: f(x)= 88.84092836716859
# differential_evolution step 293: f(x)= 88.84092836716859
# differential_evolution step 294: f(x)= 88.84092836716859
# differential_evolution step 295: f(x)= 88.81604665382362
# differential_evolution step 296: f(x)= 88.81604665382362
# differential_evolution step 297: f(x)= 88.76279452897772
# differential_evolution step 298: f(x)= 88.76279452897772
# differential_evolution step 299: f(x)= 88.15867422256292
# differential_evolution step 300: f(x)= 88.15867422256292
# differential_evolution step 301: f(x)= 88.15867422256292
# differential_evolution step 302: f(x)= 88.15867422256292
# differential_evolution step 303: f(x)= 88.15867422256292
# differential_evolution step 304: f(x)= 88.15867422256292
# differential_evolution step 305: f(x)= 88.15867422256292
# differential_evolution step 306: f(x)= 88.15867422256292
# differential_evolution step 307: f(x)= 88.15867422256292
# differential_evolution step 308: f(x)= 87.95377429779046
# differential_evolution step 309: f(x)= 87.95377429779046
# differential_evolution step 310: f(x)= 87.95377429779046
# differential_evolution step 311: f(x)= 87.95377429779046
# differential_evolution step 312: f(x)= 87.95377429779046
# differential_evolution step 313: f(x)= 87.95377429779046
# differential_evolution step 314: f(x)= 87.95377429779046
# differential_evolution step 315: f(x)= 87.69298270655408
# differential_evolution step 316: f(x)= 87.69298270655408
# differential_evolution step 317: f(x)= 87.69298270655408
# differential_evolution step 318: f(x)= 87.69298270655408
# differential_evolution step 319: f(x)= 87.69298270655408
# differential_evolution step 320: f(x)= 87.69298270655408
# differential_evolution step 321: f(x)= 87.69298270655408
# differential_evolution step 322: f(x)= 87.69298270655408
# differential_evolution step 323: f(x)= 87.64417587650652
# differential_evolution step 324: f(x)= 87.63054838699274
# differential_evolution step 325: f(x)= 87.63054838699274
# differential_evolution step 326: f(x)= 87.63054838699274
# differential_evolution step 327: f(x)= 87.63054838699274
# differential_evolution step 328: f(x)= 87.41106222491028
# differential_evolution step 329: f(x)= 87.41106222491028
# differential_evolution step 330: f(x)= 87.41106222491028
# differential_evolution step 331: f(x)= 87.41106222491028
# differential_evolution step 332: f(x)= 87.41106222491028
# differential_evolution step 333: f(x)= 87.41106222491028
# differential_evolution step 334: f(x)= 87.41106222491028
# differential_evolution step 335: f(x)= 87.41106222491028
# differential_evolution step 336: f(x)= 87.41106222491028
# differential_evolution step 337: f(x)= 87.41106222491028
# differential_evolution step 338: f(x)= 87.41106222491028
# differential_evolution step 339: f(x)= 87.41106222491028
# differential_evolution step 340: f(x)= 87.41106222491028
# differential_evolution step 341: f(x)= 87.41106222491028
# differential_evolution step 342: f(x)= 87.41106222491028
# differential_evolution step 343: f(x)= 87.41106222491028
# differential_evolution step 344: f(x)= 87.41106222491028
# differential_evolution step 345: f(x)= 87.41106222491028
# differential_evolution step 346: f(x)= 87.41106222491028
# differential_evolution step 347: f(x)= 87.41106222491028
# differential_evolution step 348: f(x)= 87.41106222491028
# differential_evolution step 349: f(x)= 87.41106222491028
# differential_evolution step 350: f(x)= 87.41106222491028
# differential_evolution step 351: f(x)= 87.21446689709553
# differential_evolution step 352: f(x)= 87.21446689709553
# differential_evolution step 353: f(x)= 87.21446689709553
# differential_evolution step 354: f(x)= 87.13603209627094
# differential_evolution step 355: f(x)= 87.13603209627094
# differential_evolution step 356: f(x)= 87.13603209627094
# differential_evolution step 357: f(x)= 87.13603209627094
# differential_evolution step 358: f(x)= 87.13603209627094
# differential_evolution step 359: f(x)= 87.13603209627094
# differential_evolution step 360: f(x)= 87.13603209627094
# differential_evolution step 361: f(x)= 87.13603209627094
# differential_evolution step 362: f(x)= 87.13603209627094
# differential_evolution step 363: f(x)= 87.13603209627094
# differential_evolution step 364: f(x)= 87.13603209627094
# differential_evolution step 365: f(x)= 87.13603209627094
# differential_evolution step 366: f(x)= 86.82616831079011
# differential_evolution step 367: f(x)= 86.82616831079011
# differential_evolution step 368: f(x)= 86.82616831079011
# differential_evolution step 369: f(x)= 86.82616831079011
# differential_evolution step 370: f(x)= 86.82616831079011
# differential_evolution step 371: f(x)= 86.82616831079011
# differential_evolution step 372: f(x)= 86.82616831079011
# differential_evolution step 373: f(x)= 86.82616831079011
# differential_evolution step 374: f(x)= 86.82616831079011
# differential_evolution step 375: f(x)= 86.82616831079011
# differential_evolution step 376: f(x)= 86.82616831079011
# differential_evolution step 377: f(x)= 86.82616831079011
# differential_evolution step 378: f(x)= 86.82616831079011
# differential_evolution step 379: f(x)= 86.82616831079011
# differential_evolution step 380: f(x)= 86.82616831079011
# differential_evolution step 381: f(x)= 86.82616831079011
# differential_evolution step 382: f(x)= 86.82616831079011
# differential_evolution step 383: f(x)= 86.82616831079011
# differential_evolution step 384: f(x)= 86.82616831079011
# differential_evolution step 385: f(x)= 86.82616831079011
# differential_evolution step 386: f(x)= 86.82616831079011
# differential_evolution step 387: f(x)= 86.82616831079011
# differential_evolution step 388: f(x)= 86.82616831079011
# differential_evolution step 389: f(x)= 86.82616831079011
# differential_evolution step 390: f(x)= 86.82616831079011
# differential_evolution step 391: f(x)= 86.82616831079011
# differential_evolution step 392: f(x)= 86.82616831079011
# differential_evolution step 393: f(x)= 86.82616831079011
# differential_evolution step 394: f(x)= 86.82616831079011
# differential_evolution step 395: f(x)= 86.82616831079011
# differential_evolution step 396: f(x)= 86.82616831079011
# differential_evolution step 397: f(x)= 86.68910270512676
# differential_evolution step 398: f(x)= 86.68910270512676
# differential_evolution step 399: f(x)= 86.68910270512676
# differential_evolution step 400: f(x)= 86.68910270512676
# differential_evolution step 401: f(x)= 86.68910270512676
# differential_evolution step 402: f(x)= 86.66218554061797
# differential_evolution step 403: f(x)= 86.66218554061797
# differential_evolution step 404: f(x)= 86.66218554061797
# differential_evolution step 405: f(x)= 86.66218554061797
# differential_evolution step 406: f(x)= 86.66218554061797
# differential_evolution step 407: f(x)= 86.66218554061797
# differential_evolution step 408: f(x)= 86.66218554061797
# differential_evolution step 409: f(x)= 86.66218554061797
# differential_evolution step 410: f(x)= 86.66218554061797
# differential_evolution step 411: f(x)= 86.66218554061797
# differential_evolution step 412: f(x)= 86.66218554061797
# differential_evolution step 413: f(x)= 86.66218554061797
# differential_evolution step 414: f(x)= 86.66218554061797
# differential_evolution step 415: f(x)= 86.66218554061797
# differential_evolution step 416: f(x)= 86.66218554061797
# differential_evolution step 417: f(x)= 86.66218554061797
# differential_evolution step 418: f(x)= 86.66218554061797
# differential_evolution step 419: f(x)= 86.66218554061797
# differential_evolution step 420: f(x)= 86.66218554061797
# differential_evolution step 421: f(x)= 86.6127240480904
# differential_evolution step 422: f(x)= 86.6127240480904
# differential_evolution step 423: f(x)= 86.57653333128592
# differential_evolution step 424: f(x)= 86.57653333128592
# differential_evolution step 425: f(x)= 86.57653333128592
# differential_evolution step 426: f(x)= 86.47116201811217
# differential_evolution step 427: f(x)= 86.47116201811217
# differential_evolution step 428: f(x)= 86.40088190921384
# differential_evolution step 429: f(x)= 86.40088190921384
# differential_evolution step 430: f(x)= 86.40088190921384
# differential_evolution step 431: f(x)= 86.40088190921384
# differential_evolution step 432: f(x)= 86.40088190921384
# differential_evolution step 433: f(x)= 86.40088190921384
# differential_evolution step 434: f(x)= 86.40088190921384
# differential_evolution step 435: f(x)= 86.40088190921384
# differential_evolution step 436: f(x)= 86.40088190921384
# differential_evolution step 437: f(x)= 86.40088190921384
# differential_evolution step 438: f(x)= 86.40088190921384
# differential_evolution step 439: f(x)= 86.40088190921384
# differential_evolution step 440: f(x)= 86.40088190921384
# differential_evolution step 441: f(x)= 86.40088190921384
# differential_evolution step 442: f(x)= 86.40088190921384
# differential_evolution step 443: f(x)= 86.40088190921384
# differential_evolution step 444: f(x)= 86.40088190921384
# differential_evolution step 445: f(x)= 86.40088190921384
# differential_evolution step 446: f(x)= 86.40088190921384
# differential_evolution step 447: f(x)= 86.40088190921384
# differential_evolution step 448: f(x)= 86.40088190921384
# differential_evolution step 449: f(x)= 86.40088190921384
# differential_evolution step 450: f(x)= 86.3402176113215
# differential_evolution step 451: f(x)= 86.3402176113215
# differential_evolution step 452: f(x)= 86.3402176113215
# differential_evolution step 453: f(x)= 86.3402176113215
# differential_evolution step 454: f(x)= 86.3402176113215
# differential_evolution step 455: f(x)= 86.3402176113215
# differential_evolution step 456: f(x)= 86.3402176113215
# differential_evolution step 457: f(x)= 86.3402176113215
# differential_evolution step 458: f(x)= 86.3402176113215
# differential_evolution step 459: f(x)= 86.3402176113215
# differential_evolution step 460: f(x)= 86.3402176113215
# differential_evolution step 461: f(x)= 86.3402176113215
# differential_evolution step 462: f(x)= 86.3402176113215
# differential_evolution step 463: f(x)= 86.3402176113215
# differential_evolution step 464: f(x)= 86.3402176113215
# differential_evolution step 465: f(x)= 86.3402176113215
# differential_evolution step 466: f(x)= 86.3402176113215
# differential_evolution step 467: f(x)= 86.3402176113215
# differential_evolution step 468: f(x)= 86.3402176113215
# differential_evolution step 469: f(x)= 86.3402176113215
# differential_evolution step 470: f(x)= 86.3402176113215
# differential_evolution step 471: f(x)= 86.3402176113215
# differential_evolution step 472: f(x)= 86.28843283094385
# differential_evolution step 473: f(x)= 86.28843283094385
# differential_evolution step 474: f(x)= 86.28843283094385
# differential_evolution step 475: f(x)= 86.28843283094385
# differential_evolution step 476: f(x)= 86.28843283094385
# differential_evolution step 477: f(x)= 86.28843283094385
# differential_evolution step 478: f(x)= 86.27327238730206
# differential_evolution step 479: f(x)= 86.27327238730206
# differential_evolution step 480: f(x)= 86.26111634860497
# differential_evolution step 481: f(x)= 86.26111634860497
# differential_evolution step 482: f(x)= 86.26111634860497
# differential_evolution step 483: f(x)= 86.22227289781036
# differential_evolution step 484: f(x)= 86.21877587609751
# differential_evolution step 485: f(x)= 86.21877587609751
# differential_evolution step 486: f(x)= 86.21877587609751
# differential_evolution step 487: f(x)= 86.21877587609751
# differential_evolution step 488: f(x)= 86.21877587609751
# differential_evolution step 489: f(x)= 86.21877587609751
# differential_evolution step 490: f(x)= 86.21877587609751
# differential_evolution step 491: f(x)= 86.21877587609751
# differential_evolution step 492: f(x)= 86.21877587609751
# differential_evolution step 493: f(x)= 86.18522583550389
# differential_evolution step 494: f(x)= 86.18522583550389
# differential_evolution step 495: f(x)= 86.18522583550389
# differential_evolution step 496: f(x)= 86.18522583550389
# differential_evolution step 497: f(x)= 86.18522583550389
# differential_evolution step 498: f(x)= 86.18522583550389
# differential_evolution step 499: f(x)= 86.18522583550389
# differential_evolution step 500: f(x)= 86.18522583550389
# differential_evolution step 501: f(x)= 86.18522583550389
# differential_evolution step 502: f(x)= 86.18522583550389
# differential_evolution step 503: f(x)= 86.18522583550389
# differential_evolution step 504: f(x)= 86.18522583550389
# differential_evolution step 505: f(x)= 86.18522583550389
# differential_evolution step 506: f(x)= 86.18522583550389
# differential_evolution step 507: f(x)= 86.18522583550389
# differential_evolution step 508: f(x)= 86.18522583550389
# differential_evolution step 509: f(x)= 86.18522583550389
# differential_evolution step 510: f(x)= 86.18522583550389
# differential_evolution step 511: f(x)= 86.18522583550389
# differential_evolution step 512: f(x)= 86.18522583550389
# differential_evolution step 513: f(x)= 86.17966058038057
# differential_evolution step 514: f(x)= 86.15738018279986
# differential_evolution step 515: f(x)= 86.13809920343353
# differential_evolution step 516: f(x)= 86.13809920343353
# differential_evolution step 517: f(x)= 86.13809920343353
# differential_evolution step 518: f(x)= 86.13809920343353
# differential_evolution step 519: f(x)= 86.13809920343353
# differential_evolution step 520: f(x)= 86.13809920343353
# differential_evolution step 521: f(x)= 86.13809920343353
# differential_evolution step 522: f(x)= 86.13809920343353
# differential_evolution step 523: f(x)= 86.13809920343353
# differential_evolution step 524: f(x)= 86.13809920343353
# differential_evolution step 525: f(x)= 86.13809920343353
# differential_evolution step 526: f(x)= 86.13809920343353
# differential_evolution step 527: f(x)= 86.13809920343353
# differential_evolution step 528: f(x)= 86.13809920343353
# differential_evolution step 529: f(x)= 86.13809920343353
# differential_evolution step 530: f(x)= 86.13809920343353
# differential_evolution step 531: f(x)= 86.13809920343353
# differential_evolution step 532: f(x)= 86.13809920343353
# differential_evolution step 533: f(x)= 86.13809920343353
# differential_evolution step 534: f(x)= 86.13809920343353
# differential_evolution step 535: f(x)= 86.13809920343353
# differential_evolution step 536: f(x)= 86.13809920343353
# differential_evolution step 537: f(x)= 86.13809920343353
# differential_evolution step 538: f(x)= 86.13809920343353
# differential_evolution step 539: f(x)= 86.13809920343353
# differential_evolution step 540: f(x)= 86.13809920343353
# differential_evolution step 541: f(x)= 86.13809920343353
# differential_evolution step 542: f(x)= 86.13809920343353
# differential_evolution step 543: f(x)= 86.13809920343353
# differential_evolution step 544: f(x)= 86.13809920343353
# differential_evolution step 545: f(x)= 86.13809920343353
# differential_evolution step 546: f(x)= 86.13809920343353
# differential_evolution step 547: f(x)= 86.13809920343353
# differential_evolution step 548: f(x)= 86.13809920343353
# differential_evolution step 549: f(x)= 86.13809920343353
# differential_evolution step 550: f(x)= 86.13809920343353
# differential_evolution step 551: f(x)= 86.13522943917555
# differential_evolution step 552: f(x)= 86.13522943917555
# differential_evolution step 553: f(x)= 86.13522943917555
# differential_evolution step 554: f(x)= 86.13522943917555
# differential_evolution step 555: f(x)= 86.11909875423368
# differential_evolution step 556: f(x)= 86.10179569301273
# differential_evolution step 557: f(x)= 86.10179569301273
# differential_evolution step 558: f(x)= 86.10179569301273
# differential_evolution step 559: f(x)= 86.10179569301273
# differential_evolution step 560: f(x)= 86.10179569301273
# differential_evolution step 561: f(x)= 86.10179569301273
# differential_evolution step 562: f(x)= 86.10179569301273
# differential_evolution step 563: f(x)= 86.10179569301273
# differential_evolution step 564: f(x)= 86.10179569301273
# differential_evolution step 565: f(x)= 86.10179569301273
# differential_evolution step 566: f(x)= 86.10179569301273
# differential_evolution step 567: f(x)= 86.10179569301273
# differential_evolution step 568: f(x)= 86.08692091478787
# differential_evolution step 569: f(x)= 86.08692091478787
# differential_evolution step 570: f(x)= 86.08692091478787
# differential_evolution step 571: f(x)= 86.08692091478787
# differential_evolution step 572: f(x)= 86.08692091478787
# differential_evolution step 573: f(x)= 86.08692091478787
# differential_evolution step 574: f(x)= 86.08692091478787
# differential_evolution step 575: f(x)= 86.08692091478787
# differential_evolution step 576: f(x)= 86.08672109145094
# differential_evolution step 577: f(x)= 86.08672109145094
# differential_evolution step 578: f(x)= 86.08672109145094
# differential_evolution step 579: f(x)= 86.08110274521702
# differential_evolution step 580: f(x)= 86.08110274521702
# differential_evolution step 581: f(x)= 86.08110274521702
# differential_evolution step 582: f(x)= 86.08110274521702
# differential_evolution step 583: f(x)= 86.08110274521702
# differential_evolution step 584: f(x)= 86.08110274521702
# differential_evolution step 585: f(x)= 86.08110274521702
# differential_evolution step 586: f(x)= 86.07675246044099
# differential_evolution step 587: f(x)= 86.07675246044099
# differential_evolution step 588: f(x)= 86.07675246044099
# differential_evolution step 589: f(x)= 86.07675246044099
# differential_evolution step 590: f(x)= 86.07675246044099
# differential_evolution step 591: f(x)= 86.07675246044099
# differential_evolution step 592: f(x)= 86.07675246044099
# differential_evolution step 593: f(x)= 86.07675246044099
# differential_evolution step 594: f(x)= 86.07675246044099
# differential_evolution step 595: f(x)= 86.07675246044099
# differential_evolution step 596: f(x)= 86.07675246044099
# differential_evolution step 597: f(x)= 86.07675246044099
# differential_evolution step 598: f(x)= 86.07675246044099
# differential_evolution step 599: f(x)= 86.07675246044099
# differential_evolution step 600: f(x)= 86.0533189678438
# differential_evolution step 601: f(x)= 86.0533189678438
# differential_evolution step 602: f(x)= 86.0533189678438
# differential_evolution step 603: f(x)= 86.0533189678438
# differential_evolution step 604: f(x)= 86.0533189678438
# differential_evolution step 605: f(x)= 86.0533189678438
# differential_evolution step 606: f(x)= 86.0533189678438
# differential_evolution step 607: f(x)= 86.0533189678438
# differential_evolution step 608: f(x)= 86.0533189678438
# differential_evolution step 609: f(x)= 86.0533189678438
# differential_evolution step 610: f(x)= 86.0533189678438
# differential_evolution step 611: f(x)= 86.0533189678438
# differential_evolution step 612: f(x)= 86.0533189678438
# differential_evolution step 613: f(x)= 86.0533189678438
# differential_evolution step 614: f(x)= 86.0533189678438
# differential_evolution step 615: f(x)= 86.0533189678438
# differential_evolution step 616: f(x)= 86.0533189678438
# differential_evolution step 617: f(x)= 86.0533189678438
# differential_evolution step 618: f(x)= 86.0533189678438
# differential_evolution step 619: f(x)= 86.0533189678438
# differential_evolution step 620: f(x)= 86.0533189678438
# differential_evolution step 621: f(x)= 86.05068880587173
# differential_evolution step 622: f(x)= 86.05068880587173
# differential_evolution step 623: f(x)= 86.05068880587173
# differential_evolution step 624: f(x)= 86.05068880587173
# differential_evolution step 625: f(x)= 86.05068880587173
# differential_evolution step 626: f(x)= 86.05068880587173
# differential_evolution step 627: f(x)= 86.05068880587173
# differential_evolution step 628: f(x)= 86.05068880587173
# differential_evolution step 629: f(x)= 86.05068880587173
# differential_evolution step 630: f(x)= 86.05068880587173
# differential_evolution step 631: f(x)= 86.05068880587173
# differential_evolution step 632: f(x)= 86.05068880587173
# differential_evolution step 633: f(x)= 86.05068880587173
# differential_evolution step 634: f(x)= 86.05068880587173
# differential_evolution step 635: f(x)= 86.05068880587173
# differential_evolution step 636: f(x)= 86.05068880587173
# differential_evolution step 637: f(x)= 86.05068880587173
# differential_evolution step 638: f(x)= 86.05068880587173
# differential_evolution step 639: f(x)= 86.05068880587173
# differential_evolution step 640: f(x)= 86.05068880587173
# differential_evolution step 641: f(x)= 86.05068880587173
# differential_evolution step 642: f(x)= 86.05068880587173
# differential_evolution step 643: f(x)= 86.05068880587173
# differential_evolution step 644: f(x)= 86.05068880587173
# differential_evolution step 645: f(x)= 86.05068880587173
# differential_evolution step 646: f(x)= 86.05068880587173
# differential_evolution step 647: f(x)= 86.05068880587173
# differential_evolution step 648: f(x)= 86.05068880587173
# differential_evolution step 649: f(x)= 86.05068880587173
# differential_evolution step 650: f(x)= 86.05068880587173
# differential_evolution step 651: f(x)= 86.05068880587173
# differential_evolution step 652: f(x)= 86.05068880587173
# differential_evolution step 653: f(x)= 86.05068880587173
# differential_evolution step 654: f(x)= 86.05068880587173
# differential_evolution step 655: f(x)= 86.05068880587173
# differential_evolution step 656: f(x)= 86.05068880587173
# differential_evolution step 657: f(x)= 86.05068880587173
# differential_evolution step 658: f(x)= 86.05068880587173
# differential_evolution step 659: f(x)= 86.05068880587173
# differential_evolution step 660: f(x)= 86.05068880587173
# differential_evolution step 661: f(x)= 86.05068880587173
# differential_evolution step 662: f(x)= 86.05068880587173
# differential_evolution step 663: f(x)= 86.04945483706801
# differential_evolution step 664: f(x)= 86.04945483706801
# differential_evolution step 665: f(x)= 86.04945483706801
# differential_evolution step 666: f(x)= 86.04945483706801
# differential_evolution step 667: f(x)= 86.04945483706801
# differential_evolution step 668: f(x)= 86.04945483706801
# differential_evolution step 669: f(x)= 86.04448387831808
# differential_evolution step 670: f(x)= 86.03932708834023
# differential_evolution step 671: f(x)= 86.03932708834023
# differential_evolution step 672: f(x)= 86.03932708834023
# differential_evolution step 673: f(x)= 86.03932708834023
# differential_evolution step 674: f(x)= 86.03932708834023
# differential_evolution step 675: f(x)= 86.0389052260821
# differential_evolution step 676: f(x)= 86.0389052260821
# differential_evolution step 677: f(x)= 86.0389052260821
# differential_evolution step 678: f(x)= 86.0389052260821
# differential_evolution step 679: f(x)= 86.0389052260821
# differential_evolution step 680: f(x)= 86.0389052260821
# differential_evolution step 681: f(x)= 86.0389052260821
# differential_evolution step 682: f(x)= 86.03251639171145
# differential_evolution step 683: f(x)= 86.03251639171145
# differential_evolution step 684: f(x)= 86.03088355331461
# differential_evolution step 685: f(x)= 86.03088355331461
# differential_evolution step 686: f(x)= 86.03088355331461
# differential_evolution step 687: f(x)= 86.03088355331461
# differential_evolution step 688: f(x)= 86.03088355331461
# differential_evolution step 689: f(x)= 86.03088355331461
# differential_evolution step 690: f(x)= 86.03088355331461
# differential_evolution step 691: f(x)= 86.03019961082174
# differential_evolution step 692: f(x)= 86.03019961082174
# differential_evolution step 693: f(x)= 86.03019961082174
# differential_evolution step 694: f(x)= 86.03019961082174
# differential_evolution step 695: f(x)= 86.03019961082174
# differential_evolution step 696: f(x)= 86.02992200792997
# differential_evolution step 697: f(x)= 86.02239719473869
# differential_evolution step 698: f(x)= 86.02239719473869
# differential_evolution step 699: f(x)= 86.02239719473869
# differential_evolution step 700: f(x)= 86.02239719473869
# differential_evolution step 701: f(x)= 86.02239719473869
# differential_evolution step 702: f(x)= 86.02239719473869
# differential_evolution step 703: f(x)= 86.02239719473869
# differential_evolution step 704: f(x)= 86.02239719473869
# differential_evolution step 705: f(x)= 86.02239719473869
# differential_evolution step 706: f(x)= 86.02239719473869
# differential_evolution step 707: f(x)= 86.02239719473869
# differential_evolution step 708: f(x)= 86.02239719473869
# differential_evolution step 709: f(x)= 86.02239719473869
# differential_evolution step 710: f(x)= 86.02239719473869
# differential_evolution step 711: f(x)= 86.01549654210835
# differential_evolution step 712: f(x)= 86.01549654210835
# differential_evolution step 713: f(x)= 86.01549654210835
# differential_evolution step 714: f(x)= 86.01549654210835
# differential_evolution step 715: f(x)= 86.01549654210835
# differential_evolution step 716: f(x)= 86.01549654210835
# differential_evolution step 717: f(x)= 86.01549654210835
# differential_evolution step 718: f(x)= 86.01549654210835
# differential_evolution step 719: f(x)= 86.01549654210835
# differential_evolution step 720: f(x)= 86.01549654210835
# differential_evolution step 721: f(x)= 86.01549654210835
# differential_evolution step 722: f(x)= 86.01549654210835
# differential_evolution step 723: f(x)= 86.01549654210835
# differential_evolution step 724: f(x)= 86.01549654210835
# differential_evolution step 725: f(x)= 86.01549654210835
# differential_evolution step 726: f(x)= 86.01549654210835
# differential_evolution step 727: f(x)= 86.01549654210835
# differential_evolution step 728: f(x)= 86.01549654210835
# differential_evolution step 729: f(x)= 86.01549654210835
# differential_evolution step 730: f(x)= 86.01509712281712
# differential_evolution step 731: f(x)= 86.01509712281712
# differential_evolution step 732: f(x)= 86.01509712281712
# differential_evolution step 733: f(x)= 86.01509712281712
# differential_evolution step 734: f(x)= 86.01509712281712
# differential_evolution step 735: f(x)= 86.01509712281712
# differential_evolution step 736: f(x)= 86.01509712281712
# differential_evolution step 737: f(x)= 86.01509712281712
# differential_evolution step 738: f(x)= 86.01509712281712
# differential_evolution step 739: f(x)= 86.01509712281712
# differential_evolution step 740: f(x)= 86.01405825728713
# differential_evolution step 741: f(x)= 86.01242104788797
# differential_evolution step 742: f(x)= 86.01242104788797
# differential_evolution step 743: f(x)= 86.01242104788797
# differential_evolution step 744: f(x)= 86.01242104788797
# differential_evolution step 745: f(x)= 86.01242104788797
# differential_evolution step 746: f(x)= 86.01242104788797
# differential_evolution step 747: f(x)= 86.01242104788797
# differential_evolution step 748: f(x)= 86.01242104788797
# differential_evolution step 749: f(x)= 86.01242104788797
# differential_evolution step 750: f(x)= 86.01242104788797
# differential_evolution step 751: f(x)= 86.01242104788797
# differential_evolution step 752: f(x)= 86.01242104788797
# differential_evolution step 753: f(x)= 86.01242104788797
# differential_evolution step 754: f(x)= 86.01076854917173
# differential_evolution step 755: f(x)= 86.01076854917173
# differential_evolution step 756: f(x)= 86.01076854917173
# differential_evolution step 757: f(x)= 86.01076854917173
# differential_evolution step 758: f(x)= 86.01076854917173
# differential_evolution step 759: f(x)= 86.01076854917173
# differential_evolution step 760: f(x)= 86.01076854917173
# differential_evolution step 761: f(x)= 86.01076854917173
# differential_evolution step 762: f(x)= 86.01076854917173
# differential_evolution step 763: f(x)= 86.01076854917173
# differential_evolution step 764: f(x)= 86.01076854917173
# differential_evolution step 765: f(x)= 86.01076854917173
# differential_evolution step 766: f(x)= 86.01076854917173
# differential_evolution step 767: f(x)= 86.01076854917173
# differential_evolution step 768: f(x)= 86.01076854917173
# differential_evolution step 769: f(x)= 86.01076854917173
# differential_evolution step 770: f(x)= 86.01076854917173
# differential_evolution step 771: f(x)= 86.00804556502104
# differential_evolution step 772: f(x)= 86.00804556502104
# differential_evolution step 773: f(x)= 86.00804556502104
# differential_evolution step 774: f(x)= 86.00804556502104
# differential_evolution step 775: f(x)= 86.00804556502104
# differential_evolution step 776: f(x)= 86.00804556502104
# differential_evolution step 777: f(x)= 86.00804556502104
# differential_evolution step 778: f(x)= 86.00804556502104
# differential_evolution step 779: f(x)= 86.00758621572328
# differential_evolution step 780: f(x)= 86.00758621572328
# differential_evolution step 781: f(x)= 86.00758621572328
# differential_evolution step 782: f(x)= 86.00758621572328
# differential_evolution step 783: f(x)= 86.00758621572328
# differential_evolution step 784: f(x)= 86.00758621572328
# differential_evolution step 785: f(x)= 86.00758621572328
# differential_evolution step 786: f(x)= 86.00716371483553
# differential_evolution step 787: f(x)= 86.00716371483553
# differential_evolution step 788: f(x)= 86.00716371483553
# differential_evolution step 789: f(x)= 86.00716371483553
# differential_evolution step 790: f(x)= 86.00716371483553
# differential_evolution step 791: f(x)= 86.00716371483553
# differential_evolution step 792: f(x)= 86.00716371483553
# differential_evolution step 793: f(x)= 86.00716371483553
# differential_evolution step 794: f(x)= 86.00716371483553
# differential_evolution step 795: f(x)= 86.00716371483553
# differential_evolution step 796: f(x)= 86.00716371483553
# differential_evolution step 797: f(x)= 86.00716371483553
# differential_evolution step 798: f(x)= 86.00716371483553
# differential_evolution step 799: f(x)= 86.00716371483553
# differential_evolution step 800: f(x)= 86.00716371483553
# differential_evolution step 801: f(x)= 86.00716371483553
# differential_evolution step 802: f(x)= 86.00716371483553
# differential_evolution step 803: f(x)= 86.00716371483553
# differential_evolution step 804: f(x)= 86.00716371483553
# differential_evolution step 805: f(x)= 86.00716371483553
# differential_evolution step 806: f(x)= 86.00716371483553
# differential_evolution step 807: f(x)= 86.00716371483553
# differential_evolution step 808: f(x)= 86.00716371483553
# differential_evolution step 809: f(x)= 86.00716371483553
# differential_evolution step 810: f(x)= 86.00716371483553
# differential_evolution step 811: f(x)= 86.00716371483553
# differential_evolution step 812: f(x)= 86.00694583704187
# differential_evolution step 813: f(x)= 86.00694583704187
# differential_evolution step 814: f(x)= 86.00615225607478
# differential_evolution step 815: f(x)= 86.00615225607478
# differential_evolution step 816: f(x)= 86.00615225607478
# differential_evolution step 817: f(x)= 86.00615225607478
# differential_evolution step 818: f(x)= 86.00615225607478
# differential_evolution step 819: f(x)= 86.00490755393665
# differential_evolution step 820: f(x)= 86.00490755393665
# differential_evolution step 821: f(x)= 86.00490755393665
# differential_evolution step 822: f(x)= 86.00490755393665
# differential_evolution step 823: f(x)= 86.00490755393665
# differential_evolution step 824: f(x)= 86.00490755393665
# differential_evolution step 825: f(x)= 86.00258104640847
# differential_evolution step 826: f(x)= 86.00258104640847
# differential_evolution step 827: f(x)= 86.00258104640847
# differential_evolution step 828: f(x)= 86.00258104640847
# differential_evolution step 829: f(x)= 86.00258104640847
# differential_evolution step 830: f(x)= 86.00258104640847
# differential_evolution step 831: f(x)= 86.00258104640847
# differential_evolution step 832: f(x)= 86.00258104640847
# differential_evolution step 833: f(x)= 86.00258104640847
# differential_evolution step 834: f(x)= 86.00258104640847
# differential_evolution step 835: f(x)= 86.00258104640847
# differential_evolution step 836: f(x)= 86.00258104640847
# differential_evolution step 837: f(x)= 86.00258104640847
# differential_evolution step 838: f(x)= 86.00258104640847
# differential_evolution step 839: f(x)= 86.00258104640847
# differential_evolution step 840: f(x)= 86.00258104640847
# differential_evolution step 841: f(x)= 86.00258104640847
# differential_evolution step 842: f(x)= 86.00258104640847
# differential_evolution step 843: f(x)= 86.00258104640847
# differential_evolution step 844: f(x)= 86.00258104640847
# differential_evolution step 845: f(x)= 86.00258104640847
# differential_evolution step 846: f(x)= 86.00258104640847
# differential_evolution step 847: f(x)= 86.00258104640847
# differential_evolution step 848: f(x)= 86.00258104640847
# differential_evolution step 849: f(x)= 86.00258104640847
# differential_evolution step 850: f(x)= 86.00258104640847
# differential_evolution step 851: f(x)= 86.00258104640847
# differential_evolution step 852: f(x)= 86.00258104640847
# differential_evolution step 853: f(x)= 86.00258104640847
# differential_evolution step 854: f(x)= 86.00258104640847
# differential_evolution step 855: f(x)= 86.00258104640847
# differential_evolution step 856: f(x)= 86.00258104640847
# differential_evolution step 857: f(x)= 86.00258104640847
# differential_evolution step 858: f(x)= 86.00258104640847
# differential_evolution step 859: f(x)= 86.00258104640847
# differential_evolution step 860: f(x)= 86.00258104640847
# differential_evolution step 861: f(x)= 86.00258104640847
# differential_evolution step 862: f(x)= 86.00231936563685
# differential_evolution step 863: f(x)= 86.00231936563685
# differential_evolution step 864: f(x)= 86.00231936563685
# differential_evolution step 865: f(x)= 86.00231936563685
# differential_evolution step 866: f(x)= 86.00231936563685
# differential_evolution step 867: f(x)= 86.00231936563685
# differential_evolution step 868: f(x)= 86.00231936563685
# differential_evolution step 869: f(x)= 86.00231936563685
# differential_evolution step 870: f(x)= 86.00231936563685
# differential_evolution step 871: f(x)= 86.00231936563685
# differential_evolution step 872: f(x)= 86.00231936563685
# differential_evolution step 873: f(x)= 86.00210301219427
# differential_evolution step 874: f(x)= 86.00210301219427
# differential_evolution step 875: f(x)= 86.00210301219427
# differential_evolution step 876: f(x)= 86.00210301219427
# differential_evolution step 877: f(x)= 86.00210301219427
# differential_evolution step 878: f(x)= 86.00210301219427
# differential_evolution step 879: f(x)= 86.00210301219427
# differential_evolution step 880: f(x)= 86.00210301219427
# differential_evolution step 881: f(x)= 86.00210301219427
# differential_evolution step 882: f(x)= 86.00210301219427
# differential_evolution step 883: f(x)= 86.00210301219427
# differential_evolution step 884: f(x)= 86.00210301219427
# differential_evolution step 885: f(x)= 86.00210301219427
# differential_evolution step 886: f(x)= 86.00159465632488
# differential_evolution step 887: f(x)= 86.00159465632488
# differential_evolution step 888: f(x)= 86.00159465632488
# differential_evolution step 889: f(x)= 86.00159465632488
# differential_evolution step 890: f(x)= 86.0010364479315
# differential_evolution step 891: f(x)= 86.0010364479315
# differential_evolution step 892: f(x)= 86.0010364479315
# differential_evolution step 893: f(x)= 86.0010364479315
# differential_evolution step 894: f(x)= 86.0010364479315
# differential_evolution step 895: f(x)= 86.0010364479315
# differential_evolution step 896: f(x)= 86.0010364479315
# differential_evolution step 897: f(x)= 86.0010364479315
# differential_evolution step 898: f(x)= 86.0010364479315
# differential_evolution step 899: f(x)= 86.0010364479315
# differential_evolution step 900: f(x)= 86.0010364479315
# differential_evolution step 901: f(x)= 86.0010364479315
# differential_evolution step 902: f(x)= 86.0010364479315
# differential_evolution step 903: f(x)= 86.0010364479315
# differential_evolution step 904: f(x)= 86.0010364479315
# differential_evolution step 905: f(x)= 86.0010364479315
# differential_evolution step 906: f(x)= 86.0010364479315
# differential_evolution step 907: f(x)= 86.0010364479315
# differential_evolution step 908: f(x)= 86.0010364479315
# differential_evolution step 909: f(x)= 86.0010364479315
# differential_evolution step 910: f(x)= 86.0010364479315
# differential_evolution step 911: f(x)= 86.0010364479315
# differential_evolution step 912: f(x)= 86.00027059329682
# differential_evolution step 913: f(x)= 86.00027059329682
# differential_evolution step 914: f(x)= 86.00027059329682
# differential_evolution step 915: f(x)= 86.00027059329682
# differential_evolution step 916: f(x)= 86.00027059329682
# differential_evolution step 917: f(x)= 86.00027059329682
# differential_evolution step 918: f(x)= 86.00027059329682
# differential_evolution step 919: f(x)= 86.00027059329682
# differential_evolution step 920: f(x)= 86.00027059329682
# differential_evolution step 921: f(x)= 86.00027059329682
# differential_evolution step 922: f(x)= 86.00027059329682
# differential_evolution step 923: f(x)= 86.00027059329682
# differential_evolution step 924: f(x)= 86.00027059329682
# differential_evolution step 925: f(x)= 86.00016680926227
# differential_evolution step 926: f(x)= 86.00016680926227
# differential_evolution step 927: f(x)= 85.99945400774263
# differential_evolution step 928: f(x)= 85.99945400774263
# differential_evolution step 929: f(x)= 85.99945400774263
# differential_evolution step 930: f(x)= 85.99945400774263
# differential_evolution step 931: f(x)= 85.99945400774263
# differential_evolution step 932: f(x)= 85.99945400774263
# differential_evolution step 933: f(x)= 85.99945400774263
# differential_evolution step 934: f(x)= 85.99945400774263
# differential_evolution step 935: f(x)= 85.99945400774263
# differential_evolution step 936: f(x)= 85.99945400774263
# differential_evolution step 937: f(x)= 85.99945400774263
# differential_evolution step 938: f(x)= 85.99945400774263
# differential_evolution step 939: f(x)= 85.99945400774263
# differential_evolution step 940: f(x)= 85.99945400774263
# differential_evolution step 941: f(x)= 85.99945400774263
# differential_evolution step 942: f(x)= 85.99945400774263
# differential_evolution step 943: f(x)= 85.99945400774263
# differential_evolution step 944: f(x)= 85.99945400774263
# differential_evolution step 945: f(x)= 85.99945400774263
# differential_evolution step 946: f(x)= 85.99945400774263
# differential_evolution step 947: f(x)= 85.99945400774263
# differential_evolution step 948: f(x)= 85.99945400774263
# differential_evolution step 949: f(x)= 85.99945400774263
# differential_evolution step 950: f(x)= 85.99945400774263
# differential_evolution step 951: f(x)= 85.99945400774263
# differential_evolution step 952: f(x)= 85.99945400774263
# differential_evolution step 953: f(x)= 85.99945400774263
# differential_evolution step 954: f(x)= 85.99945400774263
# differential_evolution step 955: f(x)= 85.99945400774263
# differential_evolution step 956: f(x)= 85.99945400774263
# differential_evolution step 957: f(x)= 85.99945400774263
# differential_evolution step 958: f(x)= 85.99945400774263
# differential_evolution step 959: f(x)= 85.99945400774263
# differential_evolution step 960: f(x)= 85.99945400774263
# differential_evolution step 961: f(x)= 85.99945400774263
# differential_evolution step 962: f(x)= 85.99945400774263
# differential_evolution step 963: f(x)= 85.99945400774263
# differential_evolution step 964: f(x)= 85.99945400774263
# differential_evolution step 965: f(x)= 85.99945400774263
# differential_evolution step 966: f(x)= 85.99945400774263
# differential_evolution step 967: f(x)= 85.9992846577191
# differential_evolution step 968: f(x)= 85.9992846577191
# differential_evolution step 969: f(x)= 85.9992846577191
# differential_evolution step 970: f(x)= 85.9992846577191
# differential_evolution step 971: f(x)= 85.9992846577191
# differential_evolution step 972: f(x)= 85.9992846577191
# differential_evolution step 973: f(x)= 85.9992846577191
# differential_evolution step 974: f(x)= 85.9992846577191
# differential_evolution step 975: f(x)= 85.9992846577191
# differential_evolution step 976: f(x)= 85.9992846577191
# differential_evolution step 977: f(x)= 85.9992846577191
# differential_evolution step 978: f(x)= 85.9992846577191
# differential_evolution step 979: f(x)= 85.9992846577191
# differential_evolution step 980: f(x)= 85.9992846577191
# differential_evolution step 981: f(x)= 85.9992846577191
# differential_evolution step 982: f(x)= 85.9992846577191
# differential_evolution step 983: f(x)= 85.9992846577191
# differential_evolution step 984: f(x)= 85.9992846577191
# differential_evolution step 985: f(x)= 85.9991898020685
# differential_evolution step 986: f(x)= 85.9991898020685
# differential_evolution step 987: f(x)= 85.9991898020685
# differential_evolution step 988: f(x)= 85.9991898020685
# differential_evolution step 989: f(x)= 85.9991898020685
# differential_evolution step 990: f(x)= 85.9991898020685
# differential_evolution step 991: f(x)= 85.9991898020685
# differential_evolution step 992: f(x)= 85.9991898020685
# differential_evolution step 993: f(x)= 85.9991898020685
# differential_evolution step 994: f(x)= 85.9991898020685
# differential_evolution step 995: f(x)= 85.99824128774003
# differential_evolution step 996: f(x)= 85.99824128774003
# differential_evolution step 997: f(x)= 85.99824128774003
# differential_evolution step 998: f(x)= 85.99824128774003
# differential_evolution step 999: f(x)= 85.99824128774003
# differential_evolution step 1000: f(x)= 85.99824128774003
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.4936, r_e=8.3473, n=1.2167, x_0=44.2733
# Sérsic 2: I_e=0.6209, r_e=24.7663, n=2.6104, x_0=51.5424
# Sérsic 3: I_e=12.1005, r_e=3.9473, n=0.8127, x_0=59.5613
# Chi quadro minimo: 85.99824128774003
# False

# %%
# Plots:
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=1.4936, r_e=8.3473, n=1.2167, x_0=44.2733
# Sérsic 2: I_e=0.6209, r_e=24.7663, n=2.6104, x_0=51.5424
# Sérsic 3: I_e=12.1005, r_e=3.9473, n=0.8127, x_0=59.5613
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/Fit/Diff_params/OIII_fit_diff.csv", index_col=0)
initial_guesses = np.concatenate([
    df['Component 1'].values,  # [I_e, r_e, n, x_0] per Component 1
    df['Component 2'].values,  # [I_e, r_e, n, x_0] per Component 2
    df['Component 3'].values   # [I_e, r_e, n, x_0] per Component 3
])
print(df)
# Out:
#      Component 1  Component 2  Component 3
# I_e       0.2457       2.2832       0.0163
# r_e      33.2419       1.5784      69.9966
# n         3.2394       0.7100       4.1528
# x_0      38.2611      48.5082      81.0023

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=initial_guesses, sigma = real_errors_OIII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1929, r_e=36.4862, n=3.3516, x_0=38.0258
# Sérsic 2: I_e=1.8072, r_e=2.1820, n=0.7398, x_0=48.7592
# Sérsic 3: I_e=0.0191, r_e=70.1221, n=3.8667, x_0=80.7547
# [2.84353111e-01 3.56063471e+01 1.62869191e+00 5.32813495e-02
#  1.18935664e+00 6.94692983e-01 5.38539802e-01 2.38984950e-01
#  1.59637593e-01 4.20977495e+02 7.64881640e+00 5.91741009e-03]
# 14.468023488130056

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_15228\444580394.py:41: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[0])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 30955.579147734516
# differential_evolution step 2: f(x)= 30955.579147734516
# differential_evolution step 3: f(x)= 16157.835038515565
# differential_evolution step 4: f(x)= 16157.835038515565
# differential_evolution step 5: f(x)= 16157.835038515565
# differential_evolution step 6: f(x)= 16157.835038515565
# differential_evolution step 7: f(x)= 16157.835038515565
# differential_evolution step 8: f(x)= 16157.835038515565
# differential_evolution step 9: f(x)= 16157.835038515565
# differential_evolution step 10: f(x)= 16157.835038515565
# differential_evolution step 11: f(x)= 13883.5763747498
# differential_evolution step 12: f(x)= 13883.5763747498
# differential_evolution step 13: f(x)= 13883.5763747498
# differential_evolution step 14: f(x)= 13883.5763747498
# differential_evolution step 15: f(x)= 13883.5763747498
# differential_evolution step 16: f(x)= 13277.365416270135
# differential_evolution step 17: f(x)= 13277.365416270135
# differential_evolution step 18: f(x)= 12895.90595647868
# differential_evolution step 19: f(x)= 12895.90595647868
# differential_evolution step 20: f(x)= 12895.90595647868
# differential_evolution step 21: f(x)= 12895.90595647868
# differential_evolution step 22: f(x)= 12895.90595647868
# differential_evolution step 23: f(x)= 12718.238939130897
# differential_evolution step 24: f(x)= 12718.238939130897
# differential_evolution step 25: f(x)= 12718.238939130897
# differential_evolution step 26: f(x)= 11903.476462233435
# differential_evolution step 27: f(x)= 11903.476462233435
# differential_evolution step 28: f(x)= 11903.476462233435
# differential_evolution step 29: f(x)= 11903.476462233435
# differential_evolution step 30: f(x)= 11903.476462233435
# differential_evolution step 31: f(x)= 11903.476462233435
# differential_evolution step 32: f(x)= 11903.476462233435
# differential_evolution step 33: f(x)= 11903.476462233435
# differential_evolution step 34: f(x)= 11852.291395065155
# differential_evolution step 35: f(x)= 11838.41046217257
# differential_evolution step 36: f(x)= 10383.215188451892
# differential_evolution step 37: f(x)= 10383.215188451892
# differential_evolution step 38: f(x)= 10383.215188451892
# differential_evolution step 39: f(x)= 10383.215188451892
# differential_evolution step 40: f(x)= 10241.85784313101
# differential_evolution step 41: f(x)= 9852.837364190158
# differential_evolution step 42: f(x)= 9852.837364190158
# differential_evolution step 43: f(x)= 9852.837364190158
# differential_evolution step 44: f(x)= 9852.837364190158
# differential_evolution step 45: f(x)= 9852.837364190158
# differential_evolution step 46: f(x)= 9852.837364190158
# differential_evolution step 47: f(x)= 9852.837364190158
# differential_evolution step 48: f(x)= 9833.834509900755
# differential_evolution step 49: f(x)= 9833.834509900755
# differential_evolution step 50: f(x)= 9833.834509900755
# differential_evolution step 51: f(x)= 9833.834509900755
# differential_evolution step 52: f(x)= 9833.834509900755
# differential_evolution step 53: f(x)= 9833.834509900755
# differential_evolution step 54: f(x)= 9833.834509900755
# differential_evolution step 55: f(x)= 9833.834509900755
# differential_evolution step 56: f(x)= 9833.834509900755
# differential_evolution step 57: f(x)= 9833.834509900755
# differential_evolution step 58: f(x)= 8910.231397335216
# differential_evolution step 59: f(x)= 8910.231397335216
# differential_evolution step 60: f(x)= 8713.9375466778
# differential_evolution step 61: f(x)= 8713.9375466778
# differential_evolution step 62: f(x)= 8713.9375466778
# differential_evolution step 63: f(x)= 8713.9375466778
# differential_evolution step 64: f(x)= 8713.9375466778
# differential_evolution step 65: f(x)= 8713.9375466778
# differential_evolution step 66: f(x)= 8713.9375466778
# differential_evolution step 67: f(x)= 8713.9375466778
# differential_evolution step 68: f(x)= 8713.9375466778
# differential_evolution step 69: f(x)= 8713.9375466778
# differential_evolution step 70: f(x)= 8713.9375466778
# differential_evolution step 71: f(x)= 8713.9375466778
# differential_evolution step 72: f(x)= 8713.9375466778
# differential_evolution step 73: f(x)= 8713.9375466778
# differential_evolution step 74: f(x)= 8713.9375466778
# differential_evolution step 75: f(x)= 8713.9375466778
# differential_evolution step 76: f(x)= 8713.9375466778
# differential_evolution step 77: f(x)= 8621.995439084358
# differential_evolution step 78: f(x)= 8621.995439084358
# differential_evolution step 79: f(x)= 8427.96153728324
# differential_evolution step 80: f(x)= 8427.96153728324
# differential_evolution step 81: f(x)= 8427.96153728324
# differential_evolution step 82: f(x)= 8329.011796291346
# differential_evolution step 83: f(x)= 8329.011796291346
# differential_evolution step 84: f(x)= 8329.011796291346
# differential_evolution step 85: f(x)= 8329.011796291346
# differential_evolution step 86: f(x)= 8211.149383633665
# differential_evolution step 87: f(x)= 8211.149383633665
# differential_evolution step 88: f(x)= 8211.149383633665
# differential_evolution step 89: f(x)= 8141.071836927793
# differential_evolution step 90: f(x)= 8141.071836927793
# differential_evolution step 91: f(x)= 8061.9071605342815
# differential_evolution step 92: f(x)= 8061.9071605342815
# differential_evolution step 93: f(x)= 8061.9071605342815
# differential_evolution step 94: f(x)= 8061.9071605342815
# differential_evolution step 95: f(x)= 8061.9071605342815
# differential_evolution step 96: f(x)= 8061.9071605342815
# differential_evolution step 97: f(x)= 8061.9071605342815
# differential_evolution step 98: f(x)= 8061.9071605342815
# differential_evolution step 99: f(x)= 8061.9071605342815
# differential_evolution step 100: f(x)= 8061.9071605342815
# differential_evolution step 101: f(x)= 8061.9071605342815
# differential_evolution step 102: f(x)= 8061.9071605342815
# differential_evolution step 103: f(x)= 8061.9071605342815
# differential_evolution step 104: f(x)= 8061.9071605342815
# differential_evolution step 105: f(x)= 8061.9071605342815
# differential_evolution step 106: f(x)= 8061.9071605342815
# differential_evolution step 107: f(x)= 8061.9071605342815
# differential_evolution step 108: f(x)= 8061.9071605342815
# differential_evolution step 109: f(x)= 7904.805441554314
# differential_evolution step 110: f(x)= 7904.805441554314
# differential_evolution step 111: f(x)= 7904.805441554314
# differential_evolution step 112: f(x)= 7593.69909494786
# differential_evolution step 113: f(x)= 7593.69909494786
# differential_evolution step 114: f(x)= 7593.69909494786
# differential_evolution step 115: f(x)= 7593.69909494786
# differential_evolution step 116: f(x)= 7593.69909494786
# differential_evolution step 117: f(x)= 7593.69909494786
# differential_evolution step 118: f(x)= 7593.69909494786
# differential_evolution step 119: f(x)= 7593.69909494786
# differential_evolution step 120: f(x)= 7593.69909494786
# differential_evolution step 121: f(x)= 7593.69909494786
# differential_evolution step 122: f(x)= 7593.69909494786
# differential_evolution step 123: f(x)= 7593.69909494786
# differential_evolution step 124: f(x)= 7593.69909494786
# differential_evolution step 125: f(x)= 7593.69909494786
# differential_evolution step 126: f(x)= 7593.69909494786
# differential_evolution step 127: f(x)= 7593.69909494786
# differential_evolution step 128: f(x)= 7593.69909494786
# differential_evolution step 129: f(x)= 7593.69909494786
# differential_evolution step 130: f(x)= 7593.69909494786
# differential_evolution step 131: f(x)= 7593.69909494786
# differential_evolution step 132: f(x)= 7593.69909494786
# differential_evolution step 133: f(x)= 7593.69909494786
# differential_evolution step 134: f(x)= 7593.69909494786
# differential_evolution step 135: f(x)= 7593.69909494786
# differential_evolution step 136: f(x)= 7593.69909494786
# differential_evolution step 137: f(x)= 7593.69909494786
# differential_evolution step 138: f(x)= 7593.69909494786
# differential_evolution step 139: f(x)= 7593.69909494786
# differential_evolution step 140: f(x)= 7593.69909494786
# differential_evolution step 141: f(x)= 7593.69909494786
# differential_evolution step 142: f(x)= 7593.69909494786
# differential_evolution step 143: f(x)= 7593.69909494786
# differential_evolution step 144: f(x)= 7593.69909494786
# differential_evolution step 145: f(x)= 7593.69909494786
# differential_evolution step 146: f(x)= 7593.69909494786
# differential_evolution step 147: f(x)= 7580.25578056545
# differential_evolution step 148: f(x)= 7580.25578056545
# differential_evolution step 149: f(x)= 7552.933003142429
# differential_evolution step 150: f(x)= 7498.580604527318
# differential_evolution step 151: f(x)= 7498.580604527318
# differential_evolution step 152: f(x)= 7498.580604527318
# differential_evolution step 153: f(x)= 7498.580604527318
# differential_evolution step 154: f(x)= 7498.580604527318
# differential_evolution step 155: f(x)= 7498.580604527318
# differential_evolution step 156: f(x)= 7498.580604527318
# differential_evolution step 157: f(x)= 7449.152717242535
# differential_evolution step 158: f(x)= 7449.152717242535
# differential_evolution step 159: f(x)= 7449.152717242535
# differential_evolution step 160: f(x)= 7449.152717242535
# differential_evolution step 161: f(x)= 7449.152717242535
# differential_evolution step 162: f(x)= 7449.152717242535
# differential_evolution step 163: f(x)= 7429.9836033269385
# differential_evolution step 164: f(x)= 7429.9836033269385
# differential_evolution step 165: f(x)= 7429.9836033269385
# differential_evolution step 166: f(x)= 7429.9836033269385
# differential_evolution step 167: f(x)= 7429.9836033269385
# differential_evolution step 168: f(x)= 7429.9836033269385
# differential_evolution step 169: f(x)= 7429.9836033269385
# differential_evolution step 170: f(x)= 7429.066009838834
# differential_evolution step 171: f(x)= 7429.066009838834
# differential_evolution step 172: f(x)= 7383.741698150165
# differential_evolution step 173: f(x)= 7383.741698150165
# differential_evolution step 174: f(x)= 7383.741698150165
# differential_evolution step 175: f(x)= 7383.741698150165
# differential_evolution step 176: f(x)= 7383.741698150165
# differential_evolution step 177: f(x)= 7383.741698150165
# differential_evolution step 178: f(x)= 7383.741698150165
# differential_evolution step 179: f(x)= 7383.741698150165
# differential_evolution step 180: f(x)= 7377.906875072645
# differential_evolution step 181: f(x)= 7377.906875072645
# differential_evolution step 182: f(x)= 7377.906875072645
# differential_evolution step 183: f(x)= 7373.77684138804
# differential_evolution step 184: f(x)= 7331.496162326426
# differential_evolution step 185: f(x)= 7331.496162326426
# differential_evolution step 186: f(x)= 7331.496162326426
# differential_evolution step 187: f(x)= 7331.496162326426
# differential_evolution step 188: f(x)= 7331.496162326426
# differential_evolution step 189: f(x)= 7330.750218558097
# differential_evolution step 190: f(x)= 7297.039927605203
# differential_evolution step 191: f(x)= 7297.039927605203
# differential_evolution step 192: f(x)= 7297.039927605203
# differential_evolution step 193: f(x)= 7297.039927605203
# differential_evolution step 194: f(x)= 7297.039927605203
# differential_evolution step 195: f(x)= 7297.039927605203
# differential_evolution step 196: f(x)= 7297.039927605203
# differential_evolution step 197: f(x)= 7297.039927605203
# differential_evolution step 198: f(x)= 7288.647148599163
# differential_evolution step 199: f(x)= 7288.647148599163
# differential_evolution step 200: f(x)= 7288.647148599163
# differential_evolution step 201: f(x)= 7288.647148599163
# differential_evolution step 202: f(x)= 7288.647148599163
# differential_evolution step 203: f(x)= 7288.647148599163
# differential_evolution step 204: f(x)= 7288.647148599163
# differential_evolution step 205: f(x)= 7288.647148599163
# differential_evolution step 206: f(x)= 7288.647148599163
# differential_evolution step 207: f(x)= 7256.9553677741405
# differential_evolution step 208: f(x)= 7256.9553677741405
# differential_evolution step 209: f(x)= 7256.9553677741405
# differential_evolution step 210: f(x)= 7256.9553677741405
# differential_evolution step 211: f(x)= 7256.9553677741405
# differential_evolution step 212: f(x)= 7243.429331968544
# differential_evolution step 213: f(x)= 7243.429331968544
# differential_evolution step 214: f(x)= 7243.429331968544
# differential_evolution step 215: f(x)= 7243.429331968544
# differential_evolution step 216: f(x)= 7243.429331968544
# differential_evolution step 217: f(x)= 7243.429331968544
# differential_evolution step 218: f(x)= 7243.429331968544
# differential_evolution step 219: f(x)= 7243.429331968544
# differential_evolution step 220: f(x)= 7243.429331968544
# differential_evolution step 221: f(x)= 7243.429331968544
# differential_evolution step 222: f(x)= 7243.429331968544
# differential_evolution step 223: f(x)= 7243.429331968544
# differential_evolution step 224: f(x)= 7214.243730426853
# differential_evolution step 225: f(x)= 7214.243730426853
# differential_evolution step 226: f(x)= 7214.243730426853
# differential_evolution step 227: f(x)= 7214.243730426853
# differential_evolution step 228: f(x)= 7214.243730426853
# differential_evolution step 229: f(x)= 7214.243730426853
# differential_evolution step 230: f(x)= 7214.243730426853
# differential_evolution step 231: f(x)= 7214.243730426853
# differential_evolution step 232: f(x)= 7214.243730426853
# differential_evolution step 233: f(x)= 7214.243730426853
# differential_evolution step 234: f(x)= 7177.001391754242
# differential_evolution step 235: f(x)= 7177.001391754242
# differential_evolution step 236: f(x)= 7177.001391754242
# differential_evolution step 237: f(x)= 7177.001391754242
# differential_evolution step 238: f(x)= 7177.001391754242
# differential_evolution step 239: f(x)= 7177.001391754242
# differential_evolution step 240: f(x)= 7177.001391754242
# differential_evolution step 241: f(x)= 7177.001391754242
# differential_evolution step 242: f(x)= 7177.001391754242
# differential_evolution step 243: f(x)= 7177.001391754242
# differential_evolution step 244: f(x)= 7177.001391754242
# differential_evolution step 245: f(x)= 7177.001391754242
# differential_evolution step 246: f(x)= 7177.001391754242
# differential_evolution step 247: f(x)= 7177.001391754242
# differential_evolution step 248: f(x)= 7177.001391754242
# differential_evolution step 249: f(x)= 7177.001391754242
# differential_evolution step 250: f(x)= 7177.001391754242
# differential_evolution step 251: f(x)= 7177.001391754242
# differential_evolution step 252: f(x)= 7177.001391754242
# differential_evolution step 253: f(x)= 7177.001391754242
# differential_evolution step 254: f(x)= 7177.001391754242
# differential_evolution step 255: f(x)= 7177.001391754242
# differential_evolution step 256: f(x)= 7177.001391754242
# differential_evolution step 257: f(x)= 7160.523425364914
# differential_evolution step 258: f(x)= 7160.523425364914
# differential_evolution step 259: f(x)= 7160.523425364914
# differential_evolution step 260: f(x)= 7160.523425364914
# differential_evolution step 261: f(x)= 7160.523425364914
# differential_evolution step 262: f(x)= 7160.523425364914
# differential_evolution step 263: f(x)= 7160.523425364914
# differential_evolution step 264: f(x)= 7160.523425364914
# differential_evolution step 265: f(x)= 7160.523425364914
# differential_evolution step 266: f(x)= 7160.523425364914
# differential_evolution step 267: f(x)= 7160.523425364914
# differential_evolution step 268: f(x)= 7160.523425364914
# differential_evolution step 269: f(x)= 7160.523425364914
# differential_evolution step 270: f(x)= 7160.523425364914
# differential_evolution step 271: f(x)= 7160.523425364914
# differential_evolution step 272: f(x)= 7160.523425364914
# differential_evolution step 273: f(x)= 7160.523425364914
# differential_evolution step 274: f(x)= 7160.523425364914
# differential_evolution step 275: f(x)= 7160.523425364914
# differential_evolution step 276: f(x)= 7160.523425364914
# differential_evolution step 277: f(x)= 7160.523425364914
# differential_evolution step 278: f(x)= 7160.523425364914
# differential_evolution step 279: f(x)= 7160.523425364914
# differential_evolution step 280: f(x)= 7160.523425364914
# differential_evolution step 281: f(x)= 7160.523425364914
# differential_evolution step 282: f(x)= 7160.523425364914
# differential_evolution step 283: f(x)= 7160.523425364914
# differential_evolution step 284: f(x)= 7160.523425364914
# differential_evolution step 285: f(x)= 7160.523425364914
# differential_evolution step 286: f(x)= 7160.523425364914
# differential_evolution step 287: f(x)= 7160.523425364914
# differential_evolution step 288: f(x)= 7160.523425364914
# differential_evolution step 289: f(x)= 7160.523425364914
# differential_evolution step 290: f(x)= 7160.523425364914
# differential_evolution step 291: f(x)= 7160.523425364914
# differential_evolution step 292: f(x)= 7160.523425364914
# differential_evolution step 293: f(x)= 7160.523425364914
# differential_evolution step 294: f(x)= 7160.523425364914
# differential_evolution step 295: f(x)= 7159.907785921969
# differential_evolution step 296: f(x)= 7159.907785921969
# differential_evolution step 297: f(x)= 7159.907785921969
# differential_evolution step 298: f(x)= 7159.907785921969
# differential_evolution step 299: f(x)= 7143.039364113871
# differential_evolution step 300: f(x)= 7142.696286626422
# differential_evolution step 301: f(x)= 7129.995461737417
# differential_evolution step 302: f(x)= 7129.995461737417
# differential_evolution step 303: f(x)= 7129.995461737417
# differential_evolution step 304: f(x)= 7129.995461737417
# differential_evolution step 305: f(x)= 7129.995461737417
# differential_evolution step 306: f(x)= 7129.995461737417
# differential_evolution step 307: f(x)= 7129.995461737417
# differential_evolution step 308: f(x)= 7129.995461737417
# differential_evolution step 309: f(x)= 7129.995461737417
# differential_evolution step 310: f(x)= 7129.995461737417
# differential_evolution step 311: f(x)= 7129.995461737417
# differential_evolution step 312: f(x)= 7129.995461737417
# differential_evolution step 313: f(x)= 7123.489517926947
# differential_evolution step 314: f(x)= 7123.489517926947
# differential_evolution step 315: f(x)= 7123.489517926947
# differential_evolution step 316: f(x)= 7123.489517926947
# differential_evolution step 317: f(x)= 7123.489517926947
# differential_evolution step 318: f(x)= 7123.489517926947
# differential_evolution step 319: f(x)= 7123.489517926947
# differential_evolution step 320: f(x)= 7123.489517926947
# differential_evolution step 321: f(x)= 7123.489517926947
# differential_evolution step 322: f(x)= 7123.489517926947
# differential_evolution step 323: f(x)= 7123.489517926947
# differential_evolution step 324: f(x)= 7123.489517926947
# differential_evolution step 325: f(x)= 7123.489517926947
# differential_evolution step 326: f(x)= 7121.492734785139
# differential_evolution step 327: f(x)= 7121.492734785139
# differential_evolution step 328: f(x)= 7121.492734785139
# differential_evolution step 329: f(x)= 7121.492734785139
# differential_evolution step 330: f(x)= 7121.492734785139
# differential_evolution step 331: f(x)= 7121.492734785139
# differential_evolution step 332: f(x)= 7121.492734785139
# differential_evolution step 333: f(x)= 7121.492734785139
# differential_evolution step 334: f(x)= 7121.492734785139
# differential_evolution step 335: f(x)= 7120.913331712865
# differential_evolution step 336: f(x)= 7120.913331712865
# differential_evolution step 337: f(x)= 7120.913331712865
# differential_evolution step 338: f(x)= 7120.913331712865
# differential_evolution step 339: f(x)= 7116.192807120944
# differential_evolution step 340: f(x)= 7111.8544266094395
# differential_evolution step 341: f(x)= 7092.910840518292
# differential_evolution step 342: f(x)= 7092.910840518292
# differential_evolution step 343: f(x)= 7092.910840518292
# differential_evolution step 344: f(x)= 7092.910840518292
# differential_evolution step 345: f(x)= 7092.910840518292
# differential_evolution step 346: f(x)= 7092.910840518292
# differential_evolution step 347: f(x)= 7092.910840518292
# differential_evolution step 348: f(x)= 7092.910840518292
# differential_evolution step 349: f(x)= 7092.910840518292
# differential_evolution step 350: f(x)= 7092.910840518292
# differential_evolution step 351: f(x)= 7092.910840518292
# differential_evolution step 352: f(x)= 7092.910840518292
# differential_evolution step 353: f(x)= 7092.910840518292
# differential_evolution step 354: f(x)= 7092.910840518292
# differential_evolution step 355: f(x)= 7092.910840518292
# differential_evolution step 356: f(x)= 7092.910840518292
# differential_evolution step 357: f(x)= 7092.910840518292
# differential_evolution step 358: f(x)= 7092.910840518292
# differential_evolution step 359: f(x)= 7092.910840518292
# differential_evolution step 360: f(x)= 7092.910840518292
# differential_evolution step 361: f(x)= 7092.910840518292
# differential_evolution step 362: f(x)= 7092.910840518292
# differential_evolution step 363: f(x)= 7092.910840518292
# differential_evolution step 364: f(x)= 7092.910840518292
# differential_evolution step 365: f(x)= 7092.910840518292
# differential_evolution step 366: f(x)= 7092.910840518292
# differential_evolution step 367: f(x)= 7092.910840518292
# differential_evolution step 368: f(x)= 7092.910840518292
# differential_evolution step 369: f(x)= 7092.910840518292
# differential_evolution step 370: f(x)= 7092.910840518292
# differential_evolution step 371: f(x)= 7092.910840518292
# differential_evolution step 372: f(x)= 7092.910840518292
# differential_evolution step 373: f(x)= 7092.910840518292
# differential_evolution step 374: f(x)= 7092.910840518292
# differential_evolution step 375: f(x)= 7081.073817844923
# differential_evolution step 376: f(x)= 7081.073817844923
# differential_evolution step 377: f(x)= 7081.073817844923
# differential_evolution step 378: f(x)= 7081.073817844923
# differential_evolution step 379: f(x)= 7081.073817844923
# differential_evolution step 380: f(x)= 7081.073817844923
# differential_evolution step 381: f(x)= 7081.073817844923
# differential_evolution step 382: f(x)= 7081.073817844923
# differential_evolution step 383: f(x)= 7081.073817844923
# differential_evolution step 384: f(x)= 7081.073817844923
# differential_evolution step 385: f(x)= 7081.073817844923
# differential_evolution step 386: f(x)= 7081.073817844923
# differential_evolution step 387: f(x)= 7081.073817844923
# differential_evolution step 388: f(x)= 7081.073817844923
# differential_evolution step 389: f(x)= 7081.073817844923
# differential_evolution step 390: f(x)= 7081.073817844923
# differential_evolution step 391: f(x)= 7081.073817844923
# differential_evolution step 392: f(x)= 7081.073817844923
# differential_evolution step 393: f(x)= 7081.073817844923
# differential_evolution step 394: f(x)= 7081.073817844923
# differential_evolution step 395: f(x)= 7081.073817844923
# differential_evolution step 396: f(x)= 7081.073817844923
# differential_evolution step 397: f(x)= 7081.073817844923
# differential_evolution step 398: f(x)= 7081.073817844923
# differential_evolution step 399: f(x)= 7081.073817844923
# differential_evolution step 400: f(x)= 7081.073817844923
# differential_evolution step 401: f(x)= 7081.073817844923
# differential_evolution step 402: f(x)= 7081.073817844923
# differential_evolution step 403: f(x)= 7081.073817844923
# differential_evolution step 404: f(x)= 7081.073817844923
# differential_evolution step 405: f(x)= 7081.073817844923
# differential_evolution step 406: f(x)= 7081.073817844923
# differential_evolution step 407: f(x)= 7081.073817844923
# differential_evolution step 408: f(x)= 7081.073817844923
# differential_evolution step 409: f(x)= 7081.073817844923
# differential_evolution step 410: f(x)= 7081.073817844923
# differential_evolution step 411: f(x)= 7081.073817844923
# differential_evolution step 412: f(x)= 7081.073817844923
# differential_evolution step 413: f(x)= 7079.734069558991
# differential_evolution step 414: f(x)= 7079.734069558991
# differential_evolution step 415: f(x)= 7079.734069558991
# differential_evolution step 416: f(x)= 7079.734069558991
# differential_evolution step 417: f(x)= 7079.734069558991
# differential_evolution step 418: f(x)= 7079.734069558991
# differential_evolution step 419: f(x)= 7079.734069558991
# differential_evolution step 420: f(x)= 7079.734069558991
# differential_evolution step 421: f(x)= 7079.734069558991
# differential_evolution step 422: f(x)= 7079.734069558991
# differential_evolution step 423: f(x)= 7079.734069558991
# differential_evolution step 424: f(x)= 7077.747847944657
# differential_evolution step 425: f(x)= 7077.747847944657
# differential_evolution step 426: f(x)= 7077.747847944657
# differential_evolution step 427: f(x)= 7077.747847944657
# differential_evolution step 428: f(x)= 7077.747847944657
# differential_evolution step 429: f(x)= 7077.747847944657
# differential_evolution step 430: f(x)= 7077.747847944657
# differential_evolution step 431: f(x)= 7077.6161480433175
# differential_evolution step 432: f(x)= 7072.478311998045
# differential_evolution step 433: f(x)= 7072.478311998045
# differential_evolution step 434: f(x)= 7072.478311998045
# differential_evolution step 435: f(x)= 7065.017033356236
# differential_evolution step 436: f(x)= 7065.017033356236
# differential_evolution step 437: f(x)= 7065.017033356236
# differential_evolution step 438: f(x)= 7065.017033356236
# differential_evolution step 439: f(x)= 7065.017033356236
# differential_evolution step 440: f(x)= 7065.017033356236
# differential_evolution step 441: f(x)= 7065.017033356236
# differential_evolution step 442: f(x)= 7065.017033356236
# differential_evolution step 443: f(x)= 7065.017033356236
# differential_evolution step 444: f(x)= 7065.017033356236
# differential_evolution step 445: f(x)= 7065.017033356236
# differential_evolution step 446: f(x)= 7065.017033356236
# differential_evolution step 447: f(x)= 7064.1051933004
# differential_evolution step 448: f(x)= 7060.601165283165
# differential_evolution step 449: f(x)= 7060.601165283165
# differential_evolution step 450: f(x)= 7060.601165283165
# differential_evolution step 451: f(x)= 7060.601165283165
# differential_evolution step 452: f(x)= 7060.601165283165
# differential_evolution step 453: f(x)= 7060.601165283165
# differential_evolution step 454: f(x)= 7060.601165283165
# differential_evolution step 455: f(x)= 7060.601165283165
# differential_evolution step 456: f(x)= 7060.601165283165
# differential_evolution step 457: f(x)= 7060.601165283165
# differential_evolution step 458: f(x)= 7060.601165283165
# differential_evolution step 459: f(x)= 7060.601165283165
# differential_evolution step 460: f(x)= 7060.601165283165
# differential_evolution step 461: f(x)= 7060.601165283165
# differential_evolution step 462: f(x)= 7060.601165283165
# differential_evolution step 463: f(x)= 7060.601165283165
# differential_evolution step 464: f(x)= 7060.601165283165
# differential_evolution step 465: f(x)= 7060.601165283165
# differential_evolution step 466: f(x)= 7056.037079031255
# differential_evolution step 467: f(x)= 7056.037079031255
# differential_evolution step 468: f(x)= 7056.037079031255
# differential_evolution step 469: f(x)= 7056.037079031255
# differential_evolution step 470: f(x)= 7053.455731366917
# differential_evolution step 471: f(x)= 7053.455731366917
# differential_evolution step 472: f(x)= 7053.455731366917
# differential_evolution step 473: f(x)= 7053.455731366917
# differential_evolution step 474: f(x)= 7053.455731366917
# differential_evolution step 475: f(x)= 7053.455731366917
# differential_evolution step 476: f(x)= 7053.455731366917
# differential_evolution step 477: f(x)= 7053.455731366917
# differential_evolution step 478: f(x)= 7053.455731366917
# differential_evolution step 479: f(x)= 7053.455731366917
# differential_evolution step 480: f(x)= 7053.455731366917
# differential_evolution step 481: f(x)= 7053.455731366917
# differential_evolution step 482: f(x)= 7053.455731366917
# differential_evolution step 483: f(x)= 7053.455731366917
# differential_evolution step 484: f(x)= 7053.455731366917
# differential_evolution step 485: f(x)= 7053.455731366917
# differential_evolution step 486: f(x)= 7053.455731366917
# differential_evolution step 487: f(x)= 7053.455731366917
# differential_evolution step 488: f(x)= 7053.455731366917
# differential_evolution step 489: f(x)= 7053.455731366917
# differential_evolution step 490: f(x)= 7053.455731366917
# differential_evolution step 491: f(x)= 7053.455731366917
# differential_evolution step 492: f(x)= 7053.455731366917
# differential_evolution step 493: f(x)= 7053.455731366917
# differential_evolution step 494: f(x)= 7053.455731366917
# differential_evolution step 495: f(x)= 7053.455731366917
# differential_evolution step 496: f(x)= 7053.455731366917
# differential_evolution step 497: f(x)= 7053.455731366917
# differential_evolution step 498: f(x)= 7053.455731366917
# differential_evolution step 499: f(x)= 7051.959850517071
# differential_evolution step 500: f(x)= 7051.959850517071
# differential_evolution step 501: f(x)= 7051.959850517071
# differential_evolution step 502: f(x)= 7051.959850517071
# differential_evolution step 503: f(x)= 7051.959850517071
# differential_evolution step 504: f(x)= 7051.959850517071
# differential_evolution step 505: f(x)= 7051.959850517071
# differential_evolution step 506: f(x)= 7051.959850517071
# differential_evolution step 507: f(x)= 7051.959850517071
# differential_evolution step 508: f(x)= 7050.680268281781
# differential_evolution step 509: f(x)= 7050.680268281781
# differential_evolution step 510: f(x)= 7050.680268281781
# differential_evolution step 511: f(x)= 7050.249595161939
# differential_evolution step 512: f(x)= 7050.249595161939
# differential_evolution step 513: f(x)= 7050.249595161939
# differential_evolution step 514: f(x)= 7050.249595161939
# differential_evolution step 515: f(x)= 7050.249595161939
# differential_evolution step 516: f(x)= 7050.249595161939
# differential_evolution step 517: f(x)= 7050.249595161939
# differential_evolution step 518: f(x)= 7050.249595161939
# differential_evolution step 519: f(x)= 7048.307620285639
# differential_evolution step 520: f(x)= 7048.307620285639
# differential_evolution step 521: f(x)= 7044.5726785486195
# differential_evolution step 522: f(x)= 7044.5726785486195
# differential_evolution step 523: f(x)= 7044.5726785486195
# differential_evolution step 524: f(x)= 7044.5726785486195
# differential_evolution step 525: f(x)= 7044.5726785486195
# differential_evolution step 526: f(x)= 7044.5726785486195
# differential_evolution step 527: f(x)= 7044.424854717779
# differential_evolution step 528: f(x)= 7044.424854717779
# differential_evolution step 529: f(x)= 7044.424854717779
# differential_evolution step 530: f(x)= 7040.985218369003
# differential_evolution step 531: f(x)= 7040.985218369003
# differential_evolution step 532: f(x)= 7040.985218369003
# differential_evolution step 533: f(x)= 7040.985218369003
# differential_evolution step 534: f(x)= 7040.985218369003
# differential_evolution step 535: f(x)= 7040.985218369003
# differential_evolution step 536: f(x)= 7040.985218369003
# differential_evolution step 537: f(x)= 7040.985218369003
# differential_evolution step 538: f(x)= 7040.985218369003
# differential_evolution step 539: f(x)= 7040.985218369003
# differential_evolution step 540: f(x)= 7040.985218369003
# differential_evolution step 541: f(x)= 7040.985218369003
# differential_evolution step 542: f(x)= 7040.985218369003
# differential_evolution step 543: f(x)= 7040.985218369003
# differential_evolution step 544: f(x)= 7038.9720669141125
# differential_evolution step 545: f(x)= 7038.9720669141125
# differential_evolution step 546: f(x)= 7038.9720669141125
# differential_evolution step 547: f(x)= 7038.9720669141125
# differential_evolution step 548: f(x)= 7038.9720669141125
# differential_evolution step 549: f(x)= 7038.742271655878
# differential_evolution step 550: f(x)= 7038.742271655878
# differential_evolution step 551: f(x)= 7038.742271655878
# differential_evolution step 552: f(x)= 7035.092126402505
# differential_evolution step 553: f(x)= 7035.092126402505
# differential_evolution step 554: f(x)= 7035.092126402505
# differential_evolution step 555: f(x)= 7035.092126402505
# differential_evolution step 556: f(x)= 7035.092126402505
# differential_evolution step 557: f(x)= 7035.066069280009
# differential_evolution step 558: f(x)= 7035.066069280009
# differential_evolution step 559: f(x)= 7035.066069280009
# differential_evolution step 560: f(x)= 7035.066069280009
# differential_evolution step 561: f(x)= 7035.066069280009
# differential_evolution step 562: f(x)= 7035.066069280009
# differential_evolution step 563: f(x)= 7035.066069280009
# differential_evolution step 564: f(x)= 7034.183324920675
# differential_evolution step 565: f(x)= 7034.183324920675
# differential_evolution step 566: f(x)= 7033.938105490761
# differential_evolution step 567: f(x)= 7033.938105490761
# differential_evolution step 568: f(x)= 7033.445015859609
# differential_evolution step 569: f(x)= 7033.445015859609
# differential_evolution step 570: f(x)= 7033.445015859609
# differential_evolution step 571: f(x)= 7033.445015859609
# differential_evolution step 572: f(x)= 7033.445015859609
# differential_evolution step 573: f(x)= 7033.406414922991
# differential_evolution step 574: f(x)= 7033.406414922991
# differential_evolution step 575: f(x)= 7033.406414922991
# differential_evolution step 576: f(x)= 7033.27980338267
# differential_evolution step 577: f(x)= 7033.27980338267
# differential_evolution step 578: f(x)= 7033.27980338267
# differential_evolution step 579: f(x)= 7033.27980338267
# differential_evolution step 580: f(x)= 7033.27980338267
# differential_evolution step 581: f(x)= 7033.27980338267
# differential_evolution step 582: f(x)= 7033.27980338267
# differential_evolution step 583: f(x)= 7033.27980338267
# differential_evolution step 584: f(x)= 7033.27980338267
# differential_evolution step 585: f(x)= 7030.761931351556
# differential_evolution step 586: f(x)= 7030.761931351556
# differential_evolution step 587: f(x)= 7029.960194394834
# differential_evolution step 588: f(x)= 7029.960194394834
# differential_evolution step 589: f(x)= 7029.960194394834
# differential_evolution step 590: f(x)= 7029.960194394834
# differential_evolution step 591: f(x)= 7029.960194394834
# differential_evolution step 592: f(x)= 7029.960194394834
# differential_evolution step 593: f(x)= 7029.960194394834
# differential_evolution step 594: f(x)= 7029.960194394834
# differential_evolution step 595: f(x)= 7029.960194394834
# differential_evolution step 596: f(x)= 7029.960194394834
# differential_evolution step 597: f(x)= 7029.960194394834
# differential_evolution step 598: f(x)= 7029.960194394834
# differential_evolution step 599: f(x)= 7029.960194394834
# differential_evolution step 600: f(x)= 7029.429518281505
# differential_evolution step 601: f(x)= 7029.429518281505
# differential_evolution step 602: f(x)= 7029.429518281505
# differential_evolution step 603: f(x)= 7029.429518281505
# differential_evolution step 604: f(x)= 7029.429518281505
# differential_evolution step 605: f(x)= 7029.429518281505
# differential_evolution step 606: f(x)= 7028.100017356175
# differential_evolution step 607: f(x)= 7028.100017356175
# differential_evolution step 608: f(x)= 7027.362067551288
# differential_evolution step 609: f(x)= 7027.362067551288
# differential_evolution step 610: f(x)= 7027.362067551288
# differential_evolution step 611: f(x)= 7027.362067551288
# differential_evolution step 612: f(x)= 7027.362067551288
# differential_evolution step 613: f(x)= 7027.362067551288
# differential_evolution step 614: f(x)= 7027.11262564963
# differential_evolution step 615: f(x)= 7027.11262564963
# differential_evolution step 616: f(x)= 7027.11262564963
# differential_evolution step 617: f(x)= 7026.836617027838
# differential_evolution step 618: f(x)= 7026.836617027838
# differential_evolution step 619: f(x)= 7026.836617027838
# differential_evolution step 620: f(x)= 7026.836617027838
# differential_evolution step 621: f(x)= 7026.836617027838
# differential_evolution step 622: f(x)= 7026.836617027838
# differential_evolution step 623: f(x)= 7026.836617027838
# differential_evolution step 624: f(x)= 7026.836617027838
# differential_evolution step 625: f(x)= 7025.984930550783
# differential_evolution step 626: f(x)= 7025.984930550783
# differential_evolution step 627: f(x)= 7025.984930550783
# differential_evolution step 628: f(x)= 7025.984930550783
# differential_evolution step 629: f(x)= 7024.808838164184
# differential_evolution step 630: f(x)= 7024.808838164184
# differential_evolution step 631: f(x)= 7024.808838164184
# differential_evolution step 632: f(x)= 7024.808838164184
# differential_evolution step 633: f(x)= 7024.808838164184
# differential_evolution step 634: f(x)= 7024.67244988902
# differential_evolution step 635: f(x)= 7024.67244988902
# differential_evolution step 636: f(x)= 7024.67244988902
# differential_evolution step 637: f(x)= 7024.67244988902
# differential_evolution step 638: f(x)= 7024.67244988902
# differential_evolution step 639: f(x)= 7024.283938544383
# differential_evolution step 640: f(x)= 7024.283938544383
# differential_evolution step 641: f(x)= 7024.283938544383
# differential_evolution step 642: f(x)= 7024.283938544383
# differential_evolution step 643: f(x)= 7024.283938544383
# differential_evolution step 644: f(x)= 7024.283938544383
# differential_evolution step 645: f(x)= 7024.283938544383
# differential_evolution step 646: f(x)= 7024.283938544383
# differential_evolution step 647: f(x)= 7024.283938544383
# differential_evolution step 648: f(x)= 7023.820582329811
# differential_evolution step 649: f(x)= 7023.820582329811
# differential_evolution step 650: f(x)= 7023.820582329811
# differential_evolution step 651: f(x)= 7023.34571160648
# differential_evolution step 652: f(x)= 7023.34571160648
# differential_evolution step 653: f(x)= 7023.34571160648
# differential_evolution step 654: f(x)= 7023.34571160648
# differential_evolution step 655: f(x)= 7023.34571160648
# differential_evolution step 656: f(x)= 7023.34571160648
# differential_evolution step 657: f(x)= 7023.34571160648
# differential_evolution step 658: f(x)= 7023.34571160648
# differential_evolution step 659: f(x)= 7023.34571160648
# differential_evolution step 660: f(x)= 7023.34571160648
# differential_evolution step 661: f(x)= 7023.34571160648
# differential_evolution step 662: f(x)= 7023.34571160648
# differential_evolution step 663: f(x)= 7022.982132055399
# differential_evolution step 664: f(x)= 7022.982132055399
# differential_evolution step 665: f(x)= 7022.982132055399
# differential_evolution step 666: f(x)= 7022.982132055399
# differential_evolution step 667: f(x)= 7022.982132055399
# differential_evolution step 668: f(x)= 7022.982132055399
# differential_evolution step 669: f(x)= 7022.982132055399
# differential_evolution step 670: f(x)= 7022.982132055399
# differential_evolution step 671: f(x)= 7022.982132055399
# differential_evolution step 672: f(x)= 7022.982132055399
# differential_evolution step 673: f(x)= 7022.531628625074
# differential_evolution step 674: f(x)= 7022.531628625074
# differential_evolution step 675: f(x)= 7022.531628625074
# differential_evolution step 676: f(x)= 7022.531628625074
# differential_evolution step 677: f(x)= 7022.531628625074
# differential_evolution step 678: f(x)= 7022.250367716279
# differential_evolution step 679: f(x)= 7021.879559421969
# differential_evolution step 680: f(x)= 7021.879559421969
# differential_evolution step 681: f(x)= 7021.879559421969
# differential_evolution step 682: f(x)= 7021.423536567277
# differential_evolution step 683: f(x)= 7021.423536567277
# differential_evolution step 684: f(x)= 7021.423536567277
# differential_evolution step 685: f(x)= 7021.423536567277
# differential_evolution step 686: f(x)= 7021.423536567277
# differential_evolution step 687: f(x)= 7021.320019698181
# differential_evolution step 688: f(x)= 7021.320019698181
# differential_evolution step 689: f(x)= 7019.948950913091
# differential_evolution step 690: f(x)= 7019.948950913091
# differential_evolution step 691: f(x)= 7019.948950913091
# differential_evolution step 692: f(x)= 7019.948950913091
# differential_evolution step 693: f(x)= 7019.948950913091
# differential_evolution step 694: f(x)= 7019.948950913091
# differential_evolution step 695: f(x)= 7019.948950913091
# differential_evolution step 696: f(x)= 7019.948950913091
# differential_evolution step 697: f(x)= 7019.948950913091
# differential_evolution step 698: f(x)= 7019.948950913091
# differential_evolution step 699: f(x)= 7019.948950913091
# differential_evolution step 700: f(x)= 7019.948950913091
# differential_evolution step 701: f(x)= 7019.948950913091
# differential_evolution step 702: f(x)= 7019.948950913091
# differential_evolution step 703: f(x)= 7019.948950913091
# differential_evolution step 704: f(x)= 7019.948950913091
# differential_evolution step 705: f(x)= 7019.948950913091
# differential_evolution step 706: f(x)= 7019.948950913091
# differential_evolution step 707: f(x)= 7019.941080704211
# differential_evolution step 708: f(x)= 7019.941080704211
# differential_evolution step 709: f(x)= 7019.941080704211
# differential_evolution step 710: f(x)= 7019.941080704211
# differential_evolution step 711: f(x)= 7019.941080704211
# differential_evolution step 712: f(x)= 7019.941080704211
# differential_evolution step 713: f(x)= 7019.771706227502
# differential_evolution step 714: f(x)= 7019.256287730203
# differential_evolution step 715: f(x)= 7019.256287730203
# differential_evolution step 716: f(x)= 7019.256287730203
# differential_evolution step 717: f(x)= 7019.256287730203
# differential_evolution step 718: f(x)= 7019.256287730203
# differential_evolution step 719: f(x)= 7019.256287730203
# differential_evolution step 720: f(x)= 7019.256287730203
# differential_evolution step 721: f(x)= 7019.256287730203
# differential_evolution step 722: f(x)= 7019.256287730203
# differential_evolution step 723: f(x)= 7019.256287730203
# differential_evolution step 724: f(x)= 7019.256287730203
# differential_evolution step 725: f(x)= 7019.256287730203
# differential_evolution step 726: f(x)= 7019.256287730203
# differential_evolution step 727: f(x)= 7019.256287730203
# differential_evolution step 728: f(x)= 7019.256287730203
# differential_evolution step 729: f(x)= 7019.256287730203
# differential_evolution step 730: f(x)= 7019.256287730203
# differential_evolution step 731: f(x)= 7019.256287730203
# differential_evolution step 732: f(x)= 7019.256287730203
# differential_evolution step 733: f(x)= 7019.256287730203
# differential_evolution step 734: f(x)= 7019.256287730203
# differential_evolution step 735: f(x)= 7019.256287730203
# differential_evolution step 736: f(x)= 7019.256287730203
# differential_evolution step 737: f(x)= 7019.256287730203
# differential_evolution step 738: f(x)= 7019.256287730203
# differential_evolution step 739: f(x)= 7019.256287730203
# differential_evolution step 740: f(x)= 7019.256287730203
# differential_evolution step 741: f(x)= 7019.256287730203
# differential_evolution step 742: f(x)= 7019.256287730203
# differential_evolution step 743: f(x)= 7019.256287730203
# differential_evolution step 744: f(x)= 7019.256287730203
# differential_evolution step 745: f(x)= 7019.153173725438
# differential_evolution step 746: f(x)= 7019.047683282518
# differential_evolution step 747: f(x)= 7019.047683282518
# differential_evolution step 748: f(x)= 7018.884408019345
# differential_evolution step 749: f(x)= 7018.884408019345
# differential_evolution step 750: f(x)= 7018.884408019345
# differential_evolution step 751: f(x)= 7018.884408019345
# differential_evolution step 752: f(x)= 7018.884408019345
# differential_evolution step 753: f(x)= 7018.884408019345
# differential_evolution step 754: f(x)= 7018.884408019345
# differential_evolution step 755: f(x)= 7018.884408019345
# differential_evolution step 756: f(x)= 7018.884408019345
# differential_evolution step 757: f(x)= 7018.375213849501
# differential_evolution step 758: f(x)= 7018.375213849501
# differential_evolution step 759: f(x)= 7018.375213849501
# differential_evolution step 760: f(x)= 7018.375213849501
# differential_evolution step 761: f(x)= 7018.375213849501
# differential_evolution step 762: f(x)= 7018.375213849501
# differential_evolution step 763: f(x)= 7018.375213849501
# differential_evolution step 764: f(x)= 7018.375213849501
# differential_evolution step 765: f(x)= 7018.375213849501
# differential_evolution step 766: f(x)= 7018.375213849501
# differential_evolution step 767: f(x)= 7018.375213849501
# differential_evolution step 768: f(x)= 7018.375213849501
# differential_evolution step 769: f(x)= 7018.375213849501
# differential_evolution step 770: f(x)= 7018.375213849501
# differential_evolution step 771: f(x)= 7018.375213849501
# differential_evolution step 772: f(x)= 7018.372400591771
# differential_evolution step 773: f(x)= 7018.372400591771
# differential_evolution step 774: f(x)= 7018.372400591771
# differential_evolution step 775: f(x)= 7018.372400591771
# differential_evolution step 776: f(x)= 7018.372400591771
# differential_evolution step 777: f(x)= 7018.372400591771
# differential_evolution step 778: f(x)= 7018.372400591771
# differential_evolution step 779: f(x)= 7018.372400591771
# differential_evolution step 780: f(x)= 7018.354298611484
# differential_evolution step 781: f(x)= 7018.354298611484
# differential_evolution step 782: f(x)= 7018.354298611484
# differential_evolution step 783: f(x)= 7018.170493372887
# differential_evolution step 784: f(x)= 7018.170493372887
# differential_evolution step 785: f(x)= 7018.170493372887
# differential_evolution step 786: f(x)= 7018.170493372887
# differential_evolution step 787: f(x)= 7018.170493372887
# differential_evolution step 788: f(x)= 7018.166230044231
# differential_evolution step 789: f(x)= 7018.166230044231
# differential_evolution step 790: f(x)= 7018.166230044231
# differential_evolution step 791: f(x)= 7018.04902901677
# differential_evolution step 792: f(x)= 7018.04902901677
# differential_evolution step 793: f(x)= 7018.04902901677
# differential_evolution step 794: f(x)= 7018.04902901677
# differential_evolution step 795: f(x)= 7018.04902901677
# differential_evolution step 796: f(x)= 7018.04902901677
# differential_evolution step 797: f(x)= 7018.04902901677
# differential_evolution step 798: f(x)= 7018.04902901677
# differential_evolution step 799: f(x)= 7018.04902901677
# differential_evolution step 800: f(x)= 7018.04902901677
# differential_evolution step 801: f(x)= 7018.04902901677
# differential_evolution step 802: f(x)= 7018.025037856651
# differential_evolution step 803: f(x)= 7018.000369943818
# differential_evolution step 804: f(x)= 7018.000369943818
# differential_evolution step 805: f(x)= 7018.000369943818
# differential_evolution step 806: f(x)= 7018.000369943818
# differential_evolution step 807: f(x)= 7018.000369943818
# differential_evolution step 808: f(x)= 7018.000369943818
# differential_evolution step 809: f(x)= 7018.000369943818
# differential_evolution step 810: f(x)= 7018.000369943818
# differential_evolution step 811: f(x)= 7018.000369943818
# differential_evolution step 812: f(x)= 7018.000369943818
# differential_evolution step 813: f(x)= 7018.000369943818
# differential_evolution step 814: f(x)= 7018.000369943818
# differential_evolution step 815: f(x)= 7018.000369943818
# differential_evolution step 816: f(x)= 7018.000369943818
# differential_evolution step 817: f(x)= 7017.980287990507
# differential_evolution step 818: f(x)= 7017.936670681256
# differential_evolution step 819: f(x)= 7017.936670681256
# differential_evolution step 820: f(x)= 7017.936670681256
# differential_evolution step 821: f(x)= 7017.936670681256
# differential_evolution step 822: f(x)= 7017.936670681256
# differential_evolution step 823: f(x)= 7017.936670681256
# differential_evolution step 824: f(x)= 7017.936670681256
# differential_evolution step 825: f(x)= 7017.936670681256
# differential_evolution step 826: f(x)= 7017.935835642878
# differential_evolution step 827: f(x)= 7017.935835642878
# differential_evolution step 828: f(x)= 7017.935835642878
# differential_evolution step 829: f(x)= 7017.935835642878
# differential_evolution step 830: f(x)= 7017.918184693747
# differential_evolution step 831: f(x)= 7017.890747356557
# differential_evolution step 832: f(x)= 7017.890747356557
# differential_evolution step 833: f(x)= 7017.890747356557
# differential_evolution step 834: f(x)= 7017.890747356557
# differential_evolution step 835: f(x)= 7017.890747356557
# differential_evolution step 836: f(x)= 7017.890747356557
# differential_evolution step 837: f(x)= 7017.890747356557
# differential_evolution step 838: f(x)= 7017.890747356557
# differential_evolution step 839: f(x)= 7017.890747356557
# differential_evolution step 840: f(x)= 7017.890747356557
# differential_evolution step 841: f(x)= 7017.890747356557
# differential_evolution step 842: f(x)= 7017.890747356557
# differential_evolution step 843: f(x)= 7017.890747356557
# differential_evolution step 844: f(x)= 7017.890747356557
# differential_evolution step 845: f(x)= 7017.889073402136
# differential_evolution step 846: f(x)= 7017.889073402136
# differential_evolution step 847: f(x)= 7017.889073402136
# differential_evolution step 848: f(x)= 7017.889073402136
# differential_evolution step 849: f(x)= 7017.869905929805
# differential_evolution step 850: f(x)= 7017.869905929805
# differential_evolution step 851: f(x)= 7017.869905929805
# differential_evolution step 852: f(x)= 7017.869905929805
# differential_evolution step 853: f(x)= 7017.858056412953
# differential_evolution step 854: f(x)= 7017.858056412953
# differential_evolution step 855: f(x)= 7017.858056412953
# differential_evolution step 856: f(x)= 7017.858056412953
# differential_evolution step 857: f(x)= 7017.858056412953
# differential_evolution step 858: f(x)= 7017.858056412953
# differential_evolution step 859: f(x)= 7017.858056412953
# differential_evolution step 860: f(x)= 7017.858056412953
# differential_evolution step 861: f(x)= 7017.858056412953
# differential_evolution step 862: f(x)= 7017.858056412953
# differential_evolution step 863: f(x)= 7017.858056412953
# differential_evolution step 864: f(x)= 7017.858056412953
# differential_evolution step 865: f(x)= 7017.858056412953
# differential_evolution step 866: f(x)= 7017.856786231149
# differential_evolution step 867: f(x)= 7017.856786231149
# differential_evolution step 868: f(x)= 7017.855675090319
# differential_evolution step 869: f(x)= 7017.855675090319
# differential_evolution step 870: f(x)= 7017.854983765852
# differential_evolution step 871: f(x)= 7017.854983765852
# differential_evolution step 872: f(x)= 7017.852740055473
# differential_evolution step 873: f(x)= 7017.852740055473
# differential_evolution step 874: f(x)= 7017.852740055473
# differential_evolution step 875: f(x)= 7017.8517972585105
# differential_evolution step 876: f(x)= 7017.8517972585105
# differential_evolution step 877: f(x)= 7017.8517972585105
# differential_evolution step 878: f(x)= 7017.8517972585105
# differential_evolution step 879: f(x)= 7017.8517972585105
# differential_evolution step 880: f(x)= 7017.851449043134
# differential_evolution step 881: f(x)= 7017.851449043134
# differential_evolution step 882: f(x)= 7017.851449043134
# differential_evolution step 883: f(x)= 7017.851449043134
# differential_evolution step 884: f(x)= 7017.851449043134
# differential_evolution step 885: f(x)= 7017.851449043134
# differential_evolution step 886: f(x)= 7017.850722595637
# differential_evolution step 887: f(x)= 7017.850722595637
# differential_evolution step 888: f(x)= 7017.850722595637
# differential_evolution step 889: f(x)= 7017.850722595637
# differential_evolution step 890: f(x)= 7017.845609586861
# differential_evolution step 891: f(x)= 7017.845609586861
# differential_evolution step 892: f(x)= 7017.845609586861
# differential_evolution step 893: f(x)= 7017.845609586861
# differential_evolution step 894: f(x)= 7017.845609586861
# differential_evolution step 895: f(x)= 7017.845609586861
# differential_evolution step 896: f(x)= 7017.845100488024
# differential_evolution step 897: f(x)= 7017.845100488024
# differential_evolution step 898: f(x)= 7017.845100488024
# differential_evolution step 899: f(x)= 7017.8450191045085
# differential_evolution step 900: f(x)= 7017.8450191045085
# differential_evolution step 901: f(x)= 7017.8450191045085
# differential_evolution step 902: f(x)= 7017.8450191045085
# differential_evolution step 903: f(x)= 7017.840818918979
# differential_evolution step 904: f(x)= 7017.840818918979
# differential_evolution step 905: f(x)= 7017.840818918979
# differential_evolution step 906: f(x)= 7017.840818918979
# differential_evolution step 907: f(x)= 7017.840818918979
# differential_evolution step 908: f(x)= 7017.840818918979
# differential_evolution step 909: f(x)= 7017.840818918979
# differential_evolution step 910: f(x)= 7017.840818918979
# differential_evolution step 911: f(x)= 7017.840818918979
# differential_evolution step 912: f(x)= 7017.840818918979
# differential_evolution step 913: f(x)= 7017.840818918979
# differential_evolution step 914: f(x)= 7017.840818918979
# differential_evolution step 915: f(x)= 7017.840818918979
# differential_evolution step 916: f(x)= 7017.840818918979
# differential_evolution step 917: f(x)= 7017.840818918979
# differential_evolution step 918: f(x)= 7017.840818918979
# differential_evolution step 919: f(x)= 7017.840818918979
# differential_evolution step 920: f(x)= 7017.840818918979
# differential_evolution step 921: f(x)= 7017.840818918979
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.2590, r_e=50.0000, n=4.0914, x_0=38.4711
# Sérsic 2: I_e=5.0000, r_e=5.0000, n=2.6588, x_0=48.3582
# Sérsic 3: I_e=0.2906, r_e=49.9996, n=4.3961, x_0=80.9032
# Chi quadro minimo: 7017.840818918979
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Sérsic 1: I_e=1.2590, r_e=50.0000, n=4.0914, x_0=38.4711
# Sérsic 2: I_e=5.0000, r_e=5.0000, n=2.6588, x_0=48.3582
# Sérsic 3: I_e=0.2906, r_e=49.9996, n=4.3961, x_0=80.9032
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.4076, r_e=49.9518, n=3.6229, x_0=38.0255
# Sérsic 2: I_e=5.0000, r_e=5.0000, n=2.6282, x_0=48.6875
# Sérsic 3: I_e=0.2098, r_e=36.2175, n=5.5329, x_0=80.5446
# [2.97443375e+00 6.48947599e+01 2.55716849e+00 6.36089695e-04
#  1.88155305e+01 1.14817807e+01 3.51242836e+00 3.47054435e-01
#  1.09135577e+00 1.24742503e+02 5.01611754e+00 2.09526900e-01]
# 78.00565979341503

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA
seeing_i = 3.174
sigma_i = seeing_i/ 2.35

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigma_i)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 34969.14533945479
# differential_evolution step 2: f(x)= 21334.58691002734
# differential_evolution step 3: f(x)= 21334.58691002734
# differential_evolution step 4: f(x)= 21334.58691002734
# differential_evolution step 5: f(x)= 21334.58691002734
# differential_evolution step 6: f(x)= 18998.491806386297
# differential_evolution step 7: f(x)= 18998.491806386297
# differential_evolution step 8: f(x)= 18998.491806386297
# differential_evolution step 9: f(x)= 18998.491806386297
# differential_evolution step 10: f(x)= 18435.564152503426
# differential_evolution step 11: f(x)= 18435.564152503426
# differential_evolution step 12: f(x)= 18435.564152503426
# differential_evolution step 13: f(x)= 18435.564152503426
# differential_evolution step 14: f(x)= 18435.564152503426
# differential_evolution step 15: f(x)= 18435.564152503426
# differential_evolution step 16: f(x)= 18435.564152503426
# differential_evolution step 17: f(x)= 18435.564152503426
# differential_evolution step 18: f(x)= 16410.866637134273
# differential_evolution step 19: f(x)= 16410.866637134273
# differential_evolution step 20: f(x)= 16410.866637134273
# differential_evolution step 21: f(x)= 16410.866637134273
# differential_evolution step 22: f(x)= 16410.866637134273
# differential_evolution step 23: f(x)= 16410.866637134273
# differential_evolution step 24: f(x)= 15764.878061018704
# differential_evolution step 25: f(x)= 15764.878061018704
# differential_evolution step 26: f(x)= 14366.809957793897
# differential_evolution step 27: f(x)= 14366.809957793897
# differential_evolution step 28: f(x)= 14366.809957793897
# differential_evolution step 29: f(x)= 14366.809957793897
# differential_evolution step 30: f(x)= 14366.809957793897
# differential_evolution step 31: f(x)= 14366.809957793897
# differential_evolution step 32: f(x)= 14366.809957793897
# differential_evolution step 33: f(x)= 14366.809957793897
# differential_evolution step 34: f(x)= 14366.809957793897
# differential_evolution step 35: f(x)= 14366.809957793897
# differential_evolution step 36: f(x)= 14366.809957793897
# differential_evolution step 37: f(x)= 14366.809957793897
# differential_evolution step 38: f(x)= 14366.809957793897
# differential_evolution step 39: f(x)= 14366.809957793897
# differential_evolution step 40: f(x)= 14366.809957793897
# differential_evolution step 41: f(x)= 14366.809957793897
# differential_evolution step 42: f(x)= 14366.809957793897
# differential_evolution step 43: f(x)= 14366.809957793897
# differential_evolution step 44: f(x)= 14366.809957793897
# differential_evolution step 45: f(x)= 14366.809957793897
# differential_evolution step 46: f(x)= 14366.809957793897
# differential_evolution step 47: f(x)= 14366.809957793897
# differential_evolution step 48: f(x)= 14366.809957793897
# differential_evolution step 49: f(x)= 14366.809957793897
# differential_evolution step 50: f(x)= 14366.809957793897
# differential_evolution step 51: f(x)= 14366.809957793897
# differential_evolution step 52: f(x)= 14366.809957793897
# differential_evolution step 53: f(x)= 14366.809957793897
# differential_evolution step 54: f(x)= 14366.809957793897
# differential_evolution step 55: f(x)= 14366.809957793897
# differential_evolution step 56: f(x)= 14366.809957793897
# differential_evolution step 57: f(x)= 14366.809957793897
# differential_evolution step 58: f(x)= 14366.809957793897
# differential_evolution step 59: f(x)= 14366.809957793897
# differential_evolution step 60: f(x)= 13973.93806243163
# differential_evolution step 61: f(x)= 13973.93806243163
# differential_evolution step 62: f(x)= 13973.93806243163
# differential_evolution step 63: f(x)= 13973.93806243163
# differential_evolution step 64: f(x)= 13973.93806243163
# differential_evolution step 65: f(x)= 13973.93806243163
# differential_evolution step 66: f(x)= 13973.93806243163
# differential_evolution step 67: f(x)= 13518.514930920986
# differential_evolution step 68: f(x)= 13518.514930920986
# differential_evolution step 69: f(x)= 13518.514930920986
# differential_evolution step 70: f(x)= 13518.514930920986
# differential_evolution step 71: f(x)= 13480.568584181194
# differential_evolution step 72: f(x)= 12589.281253302534
# differential_evolution step 73: f(x)= 12589.281253302534
# differential_evolution step 74: f(x)= 12589.281253302534
# differential_evolution step 75: f(x)= 12589.281253302534
# differential_evolution step 76: f(x)= 12589.281253302534
# differential_evolution step 77: f(x)= 12589.281253302534
# differential_evolution step 78: f(x)= 12589.281253302534
# differential_evolution step 79: f(x)= 12589.281253302534
# differential_evolution step 80: f(x)= 12589.281253302534
# differential_evolution step 81: f(x)= 12589.281253302534
# differential_evolution step 82: f(x)= 12589.281253302534
# differential_evolution step 83: f(x)= 12589.281253302534
# differential_evolution step 84: f(x)= 12589.281253302534
# differential_evolution step 85: f(x)= 12589.281253302534
# differential_evolution step 86: f(x)= 12589.281253302534
# differential_evolution step 87: f(x)= 12589.281253302534
# differential_evolution step 88: f(x)= 12589.281253302534
# differential_evolution step 89: f(x)= 12589.281253302534
# differential_evolution step 90: f(x)= 12589.281253302534
# differential_evolution step 91: f(x)= 12589.281253302534
# differential_evolution step 92: f(x)= 12589.281253302534
# differential_evolution step 93: f(x)= 12589.281253302534
# differential_evolution step 94: f(x)= 12589.281253302534
# differential_evolution step 95: f(x)= 12589.281253302534
# differential_evolution step 96: f(x)= 12589.281253302534
# differential_evolution step 97: f(x)= 12589.281253302534
# differential_evolution step 98: f(x)= 12589.281253302534
# differential_evolution step 99: f(x)= 12560.33379007319
# differential_evolution step 100: f(x)= 12560.33379007319
# differential_evolution step 101: f(x)= 12560.33379007319
# differential_evolution step 102: f(x)= 12560.33379007319
# differential_evolution step 103: f(x)= 12560.33379007319
# differential_evolution step 104: f(x)= 12560.33379007319
# differential_evolution step 105: f(x)= 12560.33379007319
# differential_evolution step 106: f(x)= 12560.33379007319
# differential_evolution step 107: f(x)= 12560.33379007319
# differential_evolution step 108: f(x)= 12560.33379007319
# differential_evolution step 109: f(x)= 12560.33379007319
# differential_evolution step 110: f(x)= 12560.33379007319
# differential_evolution step 111: f(x)= 12528.277223783807
# differential_evolution step 112: f(x)= 12424.470341420998
# differential_evolution step 113: f(x)= 12151.673950936312
# differential_evolution step 114: f(x)= 12151.673950936312
# differential_evolution step 115: f(x)= 12151.673950936312
# differential_evolution step 116: f(x)= 12151.673950936312
# differential_evolution step 117: f(x)= 12151.673950936312
# differential_evolution step 118: f(x)= 12151.673950936312
# differential_evolution step 119: f(x)= 12151.673950936312
# differential_evolution step 120: f(x)= 12151.673950936312
# differential_evolution step 121: f(x)= 12151.673950936312
# differential_evolution step 122: f(x)= 12151.673950936312
# differential_evolution step 123: f(x)= 12151.673950936312
# differential_evolution step 124: f(x)= 12151.673950936312
# differential_evolution step 125: f(x)= 12151.673950936312
# differential_evolution step 126: f(x)= 12151.673950936312
# differential_evolution step 127: f(x)= 12151.673950936312
# differential_evolution step 128: f(x)= 12151.673950936312
# differential_evolution step 129: f(x)= 12151.673950936312
# differential_evolution step 130: f(x)= 12151.673950936312
# differential_evolution step 131: f(x)= 12151.673950936312
# differential_evolution step 132: f(x)= 12151.673950936312
# differential_evolution step 133: f(x)= 12151.673950936312
# differential_evolution step 134: f(x)= 12151.673950936312
# differential_evolution step 135: f(x)= 12151.673950936312
# differential_evolution step 136: f(x)= 12099.392770810704
# differential_evolution step 137: f(x)= 12049.524442130416
# differential_evolution step 138: f(x)= 12049.524442130416
# differential_evolution step 139: f(x)= 12049.524442130416
# differential_evolution step 140: f(x)= 12049.524442130416
# differential_evolution step 141: f(x)= 12049.524442130416
# differential_evolution step 142: f(x)= 12049.524442130416
# differential_evolution step 143: f(x)= 12049.524442130416
# differential_evolution step 144: f(x)= 11925.210525109544
# differential_evolution step 145: f(x)= 11925.210525109544
# differential_evolution step 146: f(x)= 11925.210525109544
# differential_evolution step 147: f(x)= 11925.210525109544
# differential_evolution step 148: f(x)= 11925.210525109544
# differential_evolution step 149: f(x)= 11882.555345103487
# differential_evolution step 150: f(x)= 11882.555345103487
# differential_evolution step 151: f(x)= 11882.555345103487
# differential_evolution step 152: f(x)= 11882.555345103487
# differential_evolution step 153: f(x)= 11882.555345103487
# differential_evolution step 154: f(x)= 11882.555345103487
# differential_evolution step 155: f(x)= 11882.555345103487
# differential_evolution step 156: f(x)= 11882.555345103487
# differential_evolution step 157: f(x)= 11882.555345103487
# differential_evolution step 158: f(x)= 11882.555345103487
# differential_evolution step 159: f(x)= 11882.555345103487
# differential_evolution step 160: f(x)= 11882.555345103487
# differential_evolution step 161: f(x)= 11882.555345103487
# differential_evolution step 162: f(x)= 11882.555345103487
# differential_evolution step 163: f(x)= 11882.555345103487
# differential_evolution step 164: f(x)= 11882.555345103487
# differential_evolution step 165: f(x)= 11882.555345103487
# differential_evolution step 166: f(x)= 11882.555345103487
# differential_evolution step 167: f(x)= 11882.555345103487
# differential_evolution step 168: f(x)= 11882.555345103487
# differential_evolution step 169: f(x)= 11882.555345103487
# differential_evolution step 170: f(x)= 11882.555345103487
# differential_evolution step 171: f(x)= 11882.555345103487
# differential_evolution step 172: f(x)= 11882.555345103487
# differential_evolution step 173: f(x)= 11872.141573924273
# differential_evolution step 174: f(x)= 11872.141573924273
# differential_evolution step 175: f(x)= 11867.445995873542
# differential_evolution step 176: f(x)= 11867.445995873542
# differential_evolution step 177: f(x)= 11867.445995873542
# differential_evolution step 178: f(x)= 11814.301827293246
# differential_evolution step 179: f(x)= 11814.301827293246
# differential_evolution step 180: f(x)= 11814.301827293246
# differential_evolution step 181: f(x)= 11756.04590465551
# differential_evolution step 182: f(x)= 11756.04590465551
# differential_evolution step 183: f(x)= 11756.04590465551
# differential_evolution step 184: f(x)= 11756.04590465551
# differential_evolution step 185: f(x)= 11727.467731096795
# differential_evolution step 186: f(x)= 11727.467731096795
# differential_evolution step 187: f(x)= 11727.467731096795
# differential_evolution step 188: f(x)= 11727.467731096795
# differential_evolution step 189: f(x)= 11727.467731096795
# differential_evolution step 190: f(x)= 11727.467731096795
# differential_evolution step 191: f(x)= 11727.467731096795
# differential_evolution step 192: f(x)= 11727.467731096795
# differential_evolution step 193: f(x)= 11727.467731096795
# differential_evolution step 194: f(x)= 11727.467731096795
# differential_evolution step 195: f(x)= 11727.467731096795
# differential_evolution step 196: f(x)= 11727.467731096795
# differential_evolution step 197: f(x)= 11727.467731096795
# differential_evolution step 198: f(x)= 11727.467731096795
# differential_evolution step 199: f(x)= 11727.467731096795
# differential_evolution step 200: f(x)= 11727.467731096795
# differential_evolution step 201: f(x)= 11727.467731096795
# differential_evolution step 202: f(x)= 11727.467731096795
# differential_evolution step 203: f(x)= 11727.467731096795
# differential_evolution step 204: f(x)= 11727.467731096795
# differential_evolution step 205: f(x)= 11727.467731096795
# differential_evolution step 206: f(x)= 11727.467731096795
# differential_evolution step 207: f(x)= 11727.467731096795
# differential_evolution step 208: f(x)= 11727.467731096795
# differential_evolution step 209: f(x)= 11723.36152500553
# differential_evolution step 210: f(x)= 11667.7686397914
# differential_evolution step 211: f(x)= 11667.7686397914
# differential_evolution step 212: f(x)= 11667.7686397914
# differential_evolution step 213: f(x)= 11663.911480373616
# differential_evolution step 214: f(x)= 11663.911480373616
# differential_evolution step 215: f(x)= 11663.911480373616
# differential_evolution step 216: f(x)= 11663.911480373616
# differential_evolution step 217: f(x)= 11663.911480373616
# differential_evolution step 218: f(x)= 11663.911480373616
# differential_evolution step 219: f(x)= 11663.911480373616
# differential_evolution step 220: f(x)= 11615.46913628137
# differential_evolution step 221: f(x)= 11615.46913628137
# differential_evolution step 222: f(x)= 11615.46913628137
# differential_evolution step 223: f(x)= 11615.46913628137
# differential_evolution step 224: f(x)= 11615.46913628137
# differential_evolution step 225: f(x)= 11611.626771833591
# differential_evolution step 226: f(x)= 11611.626771833591
# differential_evolution step 227: f(x)= 11611.626771833591
# differential_evolution step 228: f(x)= 11611.626771833591
# differential_evolution step 229: f(x)= 11611.626771833591
# differential_evolution step 230: f(x)= 11611.626771833591
# differential_evolution step 231: f(x)= 11611.626771833591
# differential_evolution step 232: f(x)= 11611.626771833591
# differential_evolution step 233: f(x)= 11611.626771833591
# differential_evolution step 234: f(x)= 11611.626771833591
# differential_evolution step 235: f(x)= 11611.626771833591
# differential_evolution step 236: f(x)= 11611.626771833591
# differential_evolution step 237: f(x)= 11611.626771833591
# differential_evolution step 238: f(x)= 11611.626771833591
# differential_evolution step 239: f(x)= 11611.626771833591
# differential_evolution step 240: f(x)= 11611.626771833591
# differential_evolution step 241: f(x)= 11611.626771833591
# differential_evolution step 242: f(x)= 11611.626771833591
# differential_evolution step 243: f(x)= 11611.626771833591
# differential_evolution step 244: f(x)= 11611.626771833591
# differential_evolution step 245: f(x)= 11611.626771833591
# differential_evolution step 246: f(x)= 11611.626771833591
# differential_evolution step 247: f(x)= 11611.626771833591
# differential_evolution step 248: f(x)= 11584.10106144633
# differential_evolution step 249: f(x)= 11584.10106144633
# differential_evolution step 250: f(x)= 11584.10106144633
# differential_evolution step 251: f(x)= 11584.10106144633
# differential_evolution step 252: f(x)= 11584.10106144633
# differential_evolution step 253: f(x)= 11584.10106144633
# differential_evolution step 254: f(x)= 11579.651297872058
# differential_evolution step 255: f(x)= 11579.651297872058
# differential_evolution step 256: f(x)= 11579.651297872058
# differential_evolution step 257: f(x)= 11579.651297872058
# differential_evolution step 258: f(x)= 11579.651297872058
# differential_evolution step 259: f(x)= 11579.651297872058
# differential_evolution step 260: f(x)= 11579.651297872058
# differential_evolution step 261: f(x)= 11579.651297872058
# differential_evolution step 262: f(x)= 11579.651297872058
# differential_evolution step 263: f(x)= 11579.651297872058
# differential_evolution step 264: f(x)= 11579.651297872058
# differential_evolution step 265: f(x)= 11579.651297872058
# differential_evolution step 266: f(x)= 11578.844663586484
# differential_evolution step 267: f(x)= 11575.636555213869
# differential_evolution step 268: f(x)= 11575.636555213869
# differential_evolution step 269: f(x)= 11559.297128504832
# differential_evolution step 270: f(x)= 11559.297128504832
# differential_evolution step 271: f(x)= 11559.297128504832
# differential_evolution step 272: f(x)= 11559.297128504832
# differential_evolution step 273: f(x)= 11559.297128504832
# differential_evolution step 274: f(x)= 11548.878650383354
# differential_evolution step 275: f(x)= 11548.878650383354
# differential_evolution step 276: f(x)= 11548.878650383354
# differential_evolution step 277: f(x)= 11548.878650383354
# differential_evolution step 278: f(x)= 11548.878650383354
# differential_evolution step 279: f(x)= 11548.878650383354
# differential_evolution step 280: f(x)= 11548.878650383354
# differential_evolution step 281: f(x)= 11548.878650383354
# differential_evolution step 282: f(x)= 11548.878650383354
# differential_evolution step 283: f(x)= 11548.878650383354
# differential_evolution step 284: f(x)= 11533.142081530388
# differential_evolution step 285: f(x)= 11533.142081530388
# differential_evolution step 286: f(x)= 11533.142081530388
# differential_evolution step 287: f(x)= 11533.142081530388
# differential_evolution step 288: f(x)= 11533.142081530388
# differential_evolution step 289: f(x)= 11533.142081530388
# differential_evolution step 290: f(x)= 11533.142081530388
# differential_evolution step 291: f(x)= 11533.142081530388
# differential_evolution step 292: f(x)= 11533.142081530388
# differential_evolution step 293: f(x)= 11533.142081530388
# differential_evolution step 294: f(x)= 11522.856055464614
# differential_evolution step 295: f(x)= 11522.856055464614
# differential_evolution step 296: f(x)= 11522.856055464614
# differential_evolution step 297: f(x)= 11522.856055464614
# differential_evolution step 298: f(x)= 11522.856055464614
# differential_evolution step 299: f(x)= 11522.856055464614
# differential_evolution step 300: f(x)= 11519.19186927427
# differential_evolution step 301: f(x)= 11519.19186927427
# differential_evolution step 302: f(x)= 11519.19186927427
# differential_evolution step 303: f(x)= 11516.222411165665
# differential_evolution step 304: f(x)= 11516.222411165665
# differential_evolution step 305: f(x)= 11516.222411165665
# differential_evolution step 306: f(x)= 11516.222411165665
# differential_evolution step 307: f(x)= 11516.222411165665
# differential_evolution step 308: f(x)= 11516.222411165665
# differential_evolution step 309: f(x)= 11509.618454633697
# differential_evolution step 310: f(x)= 11509.618454633697
# differential_evolution step 311: f(x)= 11509.618454633697
# differential_evolution step 312: f(x)= 11509.618454633697
# differential_evolution step 313: f(x)= 11509.618454633697
# differential_evolution step 314: f(x)= 11509.618454633697
# differential_evolution step 315: f(x)= 11509.618454633697
# differential_evolution step 316: f(x)= 11509.618454633697
# differential_evolution step 317: f(x)= 11509.618454633697
# differential_evolution step 318: f(x)= 11507.240840489561
# differential_evolution step 319: f(x)= 11507.240840489561
# differential_evolution step 320: f(x)= 11507.240840489561
# differential_evolution step 321: f(x)= 11507.240840489561
# differential_evolution step 322: f(x)= 11505.743103070676
# differential_evolution step 323: f(x)= 11505.743103070676
# differential_evolution step 324: f(x)= 11505.743103070676
# differential_evolution step 325: f(x)= 11505.743103070676
# differential_evolution step 326: f(x)= 11505.743103070676
# differential_evolution step 327: f(x)= 11505.743103070676
# differential_evolution step 328: f(x)= 11498.707954670932
# differential_evolution step 329: f(x)= 11491.03344066593
# differential_evolution step 330: f(x)= 11491.03344066593
# differential_evolution step 331: f(x)= 11491.03344066593
# differential_evolution step 332: f(x)= 11491.03344066593
# differential_evolution step 333: f(x)= 11491.03344066593
# differential_evolution step 334: f(x)= 11491.03344066593
# differential_evolution step 335: f(x)= 11483.174367816368
# differential_evolution step 336: f(x)= 11483.174367816368
# differential_evolution step 337: f(x)= 11483.174367816368
# differential_evolution step 338: f(x)= 11483.174367816368
# differential_evolution step 339: f(x)= 11483.174367816368
# differential_evolution step 340: f(x)= 11483.174367816368
# differential_evolution step 341: f(x)= 11483.174367816368
# differential_evolution step 342: f(x)= 11483.174367816368
# differential_evolution step 343: f(x)= 11483.174367816368
# differential_evolution step 344: f(x)= 11483.174367816368
# differential_evolution step 345: f(x)= 11483.174367816368
# differential_evolution step 346: f(x)= 11483.174367816368
# differential_evolution step 347: f(x)= 11483.174367816368
# differential_evolution step 348: f(x)= 11483.174367816368
# differential_evolution step 349: f(x)= 11483.174367816368
# differential_evolution step 350: f(x)= 11483.174367816368
# differential_evolution step 351: f(x)= 11483.174367816368
# differential_evolution step 352: f(x)= 11483.174367816368
# differential_evolution step 353: f(x)= 11483.174367816368
# differential_evolution step 354: f(x)= 11482.177003901035
# differential_evolution step 355: f(x)= 11482.177003901035
# differential_evolution step 356: f(x)= 11482.177003901035
# differential_evolution step 357: f(x)= 11482.177003901035
# differential_evolution step 358: f(x)= 11482.177003901035
# differential_evolution step 359: f(x)= 11482.177003901035
# differential_evolution step 360: f(x)= 11482.177003901035
# differential_evolution step 361: f(x)= 11482.177003901035
# differential_evolution step 362: f(x)= 11482.177003901035
# differential_evolution step 363: f(x)= 11482.177003901035
# differential_evolution step 364: f(x)= 11482.177003901035
# differential_evolution step 365: f(x)= 11482.177003901035
# differential_evolution step 366: f(x)= 11482.177003901035
# differential_evolution step 367: f(x)= 11482.177003901035
# differential_evolution step 368: f(x)= 11482.177003901035
# differential_evolution step 369: f(x)= 11480.840681411571
# differential_evolution step 370: f(x)= 11480.840681411571
# differential_evolution step 371: f(x)= 11480.840681411571
# differential_evolution step 372: f(x)= 11471.567891156687
# differential_evolution step 373: f(x)= 11471.567891156687
# differential_evolution step 374: f(x)= 11471.567891156687
# differential_evolution step 375: f(x)= 11468.146789575208
# differential_evolution step 376: f(x)= 11468.146789575208
# differential_evolution step 377: f(x)= 11468.146789575208
# differential_evolution step 378: f(x)= 11468.146789575208
# differential_evolution step 379: f(x)= 11468.146789575208
# differential_evolution step 380: f(x)= 11468.146789575208
# differential_evolution step 381: f(x)= 11468.146789575208
# differential_evolution step 382: f(x)= 11468.146789575208
# differential_evolution step 383: f(x)= 11468.146789575208
# differential_evolution step 384: f(x)= 11468.146789575208
# differential_evolution step 385: f(x)= 11468.146789575208
# differential_evolution step 386: f(x)= 11468.146789575208
# differential_evolution step 387: f(x)= 11468.146789575208
# differential_evolution step 388: f(x)= 11468.146789575208
# differential_evolution step 389: f(x)= 11468.146789575208
# differential_evolution step 390: f(x)= 11468.146789575208
# differential_evolution step 391: f(x)= 11468.146789575208
# differential_evolution step 392: f(x)= 11465.376092679711
# differential_evolution step 393: f(x)= 11465.376092679711
# differential_evolution step 394: f(x)= 11465.376092679711
# differential_evolution step 395: f(x)= 11460.563161847589
# differential_evolution step 396: f(x)= 11460.563161847589
# differential_evolution step 397: f(x)= 11460.563161847589
# differential_evolution step 398: f(x)= 11460.563161847589
# differential_evolution step 399: f(x)= 11460.563161847589
# differential_evolution step 400: f(x)= 11460.563161847589
# differential_evolution step 401: f(x)= 11460.563161847589
# differential_evolution step 402: f(x)= 11460.563161847589
# differential_evolution step 403: f(x)= 11460.563161847589
# differential_evolution step 404: f(x)= 11460.563161847589
# differential_evolution step 405: f(x)= 11460.563161847589
# differential_evolution step 406: f(x)= 11460.563161847589
# differential_evolution step 407: f(x)= 11460.563161847589
# differential_evolution step 408: f(x)= 11460.563161847589
# differential_evolution step 409: f(x)= 11460.563161847589
# differential_evolution step 410: f(x)= 11460.563161847589
# differential_evolution step 411: f(x)= 11460.563161847589
# differential_evolution step 412: f(x)= 11460.563161847589
# differential_evolution step 413: f(x)= 11459.596704882337
# differential_evolution step 414: f(x)= 11455.807013124364
# differential_evolution step 415: f(x)= 11455.807013124364
# differential_evolution step 416: f(x)= 11455.807013124364
# differential_evolution step 417: f(x)= 11455.807013124364
# differential_evolution step 418: f(x)= 11455.807013124364
# differential_evolution step 419: f(x)= 11455.807013124364
# differential_evolution step 420: f(x)= 11454.848643992795
# differential_evolution step 421: f(x)= 11454.848643992795
# differential_evolution step 422: f(x)= 11454.848643992795
# differential_evolution step 423: f(x)= 11449.500651493227
# differential_evolution step 424: f(x)= 11449.500651493227
# differential_evolution step 425: f(x)= 11449.500651493227
# differential_evolution step 426: f(x)= 11449.500651493227
# differential_evolution step 427: f(x)= 11449.500651493227
# differential_evolution step 428: f(x)= 11449.500651493227
# differential_evolution step 429: f(x)= 11449.500651493227
# differential_evolution step 430: f(x)= 11449.500651493227
# differential_evolution step 431: f(x)= 11449.500651493227
# differential_evolution step 432: f(x)= 11449.500651493227
# differential_evolution step 433: f(x)= 11449.500651493227
# differential_evolution step 434: f(x)= 11449.500651493227
# differential_evolution step 435: f(x)= 11449.500651493227
# differential_evolution step 436: f(x)= 11448.293919464953
# differential_evolution step 437: f(x)= 11448.293919464953
# differential_evolution step 438: f(x)= 11448.293919464953
# differential_evolution step 439: f(x)= 11448.293919464953
# differential_evolution step 440: f(x)= 11448.293919464953
# differential_evolution step 441: f(x)= 11448.293919464953
# differential_evolution step 442: f(x)= 11445.413191298952
# differential_evolution step 443: f(x)= 11445.413191298952
# differential_evolution step 444: f(x)= 11445.413191298952
# differential_evolution step 445: f(x)= 11445.413191298952
# differential_evolution step 446: f(x)= 11445.413191298952
# differential_evolution step 447: f(x)= 11445.413191298952
# differential_evolution step 448: f(x)= 11445.413191298952
# differential_evolution step 449: f(x)= 11445.07491019245
# differential_evolution step 450: f(x)= 11445.07491019245
# differential_evolution step 451: f(x)= 11445.07491019245
# differential_evolution step 452: f(x)= 11445.07491019245
# differential_evolution step 453: f(x)= 11445.07491019245
# differential_evolution step 454: f(x)= 11445.07491019245
# differential_evolution step 455: f(x)= 11445.07491019245
# differential_evolution step 456: f(x)= 11445.07491019245
# differential_evolution step 457: f(x)= 11445.07491019245
# differential_evolution step 458: f(x)= 11444.311051893463
# differential_evolution step 459: f(x)= 11444.311051893463
# differential_evolution step 460: f(x)= 11444.311051893463
# differential_evolution step 461: f(x)= 11444.311051893463
# differential_evolution step 462: f(x)= 11444.164800444525
# differential_evolution step 463: f(x)= 11444.164800444525
# differential_evolution step 464: f(x)= 11444.164800444525
# differential_evolution step 465: f(x)= 11444.13589356465
# differential_evolution step 466: f(x)= 11443.220269669342
# differential_evolution step 467: f(x)= 11443.220269669342
# differential_evolution step 468: f(x)= 11443.220269669342
# differential_evolution step 469: f(x)= 11440.163369668322
# differential_evolution step 470: f(x)= 11440.163369668322
# differential_evolution step 471: f(x)= 11440.163369668322
# differential_evolution step 472: f(x)= 11440.163369668322
# differential_evolution step 473: f(x)= 11440.163369668322
# differential_evolution step 474: f(x)= 11440.163369668322
# differential_evolution step 475: f(x)= 11440.163369668322
# differential_evolution step 476: f(x)= 11440.163369668322
# differential_evolution step 477: f(x)= 11440.163369668322
# differential_evolution step 478: f(x)= 11440.163369668322
# differential_evolution step 479: f(x)= 11440.163369668322
# differential_evolution step 480: f(x)= 11439.474015837086
# differential_evolution step 481: f(x)= 11439.474015837086
# differential_evolution step 482: f(x)= 11439.474015837086

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigma_i,
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
bounds = bounds_HA
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigma_i, *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigma_i, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6000)*(wv < 6500)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %%
d1 = {'Name': ['Continuum 3'], 'Chi squared': chi2_continuum_3,
      'Dof': dof_continuum_3, 'Chi reduced': chi2_reduced_continuum_3}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_continuum_3.csv", index= False)

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %%
mask_continuum_3 = (wv > 6450)*(wv < 6500)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_HA, label = 'Halpha') 
plt.plot(x_axes, radial_profile_continuum_3, label = 'Continuum')
plt.title(r'Halpha and Continuum NGC3049')
plt.legend()
plt.xlabel('Pixel')
plt.ylabel(r'Flux [$10^{-16}$ erg/(cm$^2$ s Å)]')
plt.grid(alpha = 0.3)
plt.savefig('Halpha_continuum_NGC3049')
