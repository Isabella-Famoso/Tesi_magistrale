# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     387   (2094, 965)   float32
#   1  IMAGE.ERR     1 ImageHDU        68   (2094, 965)   float32

# %%
image_cut = image[67:167, 0:1890]
image_error_cut = image_error[67:167, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.00485
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
seeing = 1.984
sigma = seeing / 2.35
n_component = 3

# %%
l_HA
# Out:
# 6594.830550000001

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[67:167, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3049/FORS2.2022-01-16T07_25_38.100/NGC-3049_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     387   (2094, 965)   float32
#   1  IMAGE.ERR     1 ImageHDU        68   (2094, 965)   float32
# Text(0.5, 0, 'wavelength')

# %%
mask_sky = (y > 22)*(y < 32)
mask_wv = wv > 4450.5
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) +
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs):
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 85)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100

    (0, 5),
    (0, 50),
    (0.1, 10),
    (45, 55),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (75, 85)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 4156.496936437461
# differential_evolution step 2: f(x)= 4156.496936437461
# differential_evolution step 3: f(x)= 4156.496936437461
# differential_evolution step 4: f(x)= 2124.2485727812764
# differential_evolution step 5: f(x)= 1677.9520018156488
# differential_evolution step 6: f(x)= 1677.9520018156488
# differential_evolution step 7: f(x)= 1677.9520018156488
# differential_evolution step 8: f(x)= 1677.9520018156488
# differential_evolution step 9: f(x)= 1677.9520018156488
# differential_evolution step 10: f(x)= 1677.9520018156488
# differential_evolution step 11: f(x)= 1677.9520018156488
# differential_evolution step 12: f(x)= 1034.4520300210115
# differential_evolution step 13: f(x)= 1034.4520300210115
# differential_evolution step 14: f(x)= 1034.4520300210115
# differential_evolution step 15: f(x)= 1034.4520300210115
# differential_evolution step 16: f(x)= 1034.4520300210115
# differential_evolution step 17: f(x)= 809.4719302775213
# differential_evolution step 18: f(x)= 809.4719302775213
# differential_evolution step 19: f(x)= 809.4719302775213
# differential_evolution step 20: f(x)= 809.4719302775213
# differential_evolution step 21: f(x)= 809.4719302775213
# differential_evolution step 22: f(x)= 809.4719302775213
# differential_evolution step 23: f(x)= 809.4719302775213
# differential_evolution step 24: f(x)= 809.4719302775213
# differential_evolution step 25: f(x)= 809.4719302775213
# differential_evolution step 26: f(x)= 809.4719302775213
# differential_evolution step 27: f(x)= 809.4719302775213
# differential_evolution step 28: f(x)= 809.4719302775213
# differential_evolution step 29: f(x)= 809.4719302775213
# differential_evolution step 30: f(x)= 809.4719302775213
# differential_evolution step 31: f(x)= 809.4719302775213
# differential_evolution step 32: f(x)= 809.4719302775213
# differential_evolution step 33: f(x)= 809.4719302775213
# differential_evolution step 34: f(x)= 809.4719302775213
# differential_evolution step 35: f(x)= 802.4586003991211
# differential_evolution step 36: f(x)= 802.4586003991211
# differential_evolution step 37: f(x)= 802.4586003991211
# differential_evolution step 38: f(x)= 802.4586003991211
# differential_evolution step 39: f(x)= 775.2262582981331
# differential_evolution step 40: f(x)= 775.2262582981331
# differential_evolution step 41: f(x)= 775.2262582981331
# differential_evolution step 42: f(x)= 768.99247788074
# differential_evolution step 43: f(x)= 766.3652960260778
# differential_evolution step 44: f(x)= 755.9715583548395
# differential_evolution step 45: f(x)= 755.9715583548395
# differential_evolution step 46: f(x)= 755.9715583548395
# differential_evolution step 47: f(x)= 755.9715583548395
# differential_evolution step 48: f(x)= 751.2447208567397
# differential_evolution step 49: f(x)= 751.2447208567397
# differential_evolution step 50: f(x)= 751.2447208567397
# differential_evolution step 51: f(x)= 751.2447208567397
# differential_evolution step 52: f(x)= 751.2447208567397
# differential_evolution step 53: f(x)= 751.2447208567397
# differential_evolution step 54: f(x)= 750.8498095304928
# differential_evolution step 55: f(x)= 750.8498095304928
# differential_evolution step 56: f(x)= 750.8498095304928
# differential_evolution step 57: f(x)= 750.8498095304928
# differential_evolution step 58: f(x)= 747.8861213510404
# differential_evolution step 59: f(x)= 747.8861213510404
# differential_evolution step 60: f(x)= 746.6397354398001
# differential_evolution step 61: f(x)= 746.0077537669014
# differential_evolution step 62: f(x)= 746.0077537669014
# differential_evolution step 63: f(x)= 744.5089173418531
# differential_evolution step 64: f(x)= 744.5089173418531
# differential_evolution step 65: f(x)= 743.5817786400698
# differential_evolution step 66: f(x)= 743.5817786400698
# differential_evolution step 67: f(x)= 742.9108571096427
# differential_evolution step 68: f(x)= 742.9108571096427
# differential_evolution step 69: f(x)= 742.9108571096427
# differential_evolution step 70: f(x)= 742.4861727115124
# differential_evolution step 71: f(x)= 742.4861727115124
# differential_evolution step 72: f(x)= 742.2506626676595
# differential_evolution step 73: f(x)= 741.8873493566673
# differential_evolution step 74: f(x)= 741.0849634394448
# differential_evolution step 75: f(x)= 739.8271468357714
# differential_evolution step 76: f(x)= 739.8271468357714
# differential_evolution step 77: f(x)= 739.8271468357714
# differential_evolution step 78: f(x)= 739.8271468357714
# differential_evolution step 79: f(x)= 739.8271468357714
# differential_evolution step 80: f(x)= 739.8271468357714
# differential_evolution step 81: f(x)= 737.490182159409
# differential_evolution step 82: f(x)= 737.490182159409
# differential_evolution step 83: f(x)= 737.490182159409
# differential_evolution step 84: f(x)= 737.490182159409
# differential_evolution step 85: f(x)= 737.490182159409
# differential_evolution step 86: f(x)= 737.490182159409
# differential_evolution step 87: f(x)= 737.490182159409
# differential_evolution step 88: f(x)= 737.490182159409
# differential_evolution step 89: f(x)= 737.490182159409
# differential_evolution step 90: f(x)= 737.490182159409
# differential_evolution step 91: f(x)= 737.1381428891871
# differential_evolution step 92: f(x)= 737.1381428891871
# differential_evolution step 93: f(x)= 737.1381428891871
# differential_evolution step 94: f(x)= 737.1381428891871
# differential_evolution step 95: f(x)= 737.1381428891871
# differential_evolution step 96: f(x)= 737.1381428891871
# differential_evolution step 97: f(x)= 737.1381428891871
# differential_evolution step 98: f(x)= 737.1381428891871
# differential_evolution step 99: f(x)= 737.1381428891871
# differential_evolution step 100: f(x)= 737.0978888674604
# differential_evolution step 101: f(x)= 737.0978888674604
# differential_evolution step 102: f(x)= 737.0978888674604
# differential_evolution step 103: f(x)= 737.0978888674604
# differential_evolution step 104: f(x)= 737.0978888674604
# differential_evolution step 105: f(x)= 737.0978888674604
# differential_evolution step 106: f(x)= 737.0978888674604
# differential_evolution step 107: f(x)= 737.0978888674604
# differential_evolution step 108: f(x)= 736.8111540443301
# differential_evolution step 109: f(x)= 736.4768015757113
# differential_evolution step 110: f(x)= 736.4768015757113
# differential_evolution step 111: f(x)= 736.4690695389974
# differential_evolution step 112: f(x)= 736.4690695389974
# differential_evolution step 113: f(x)= 736.4690695389974
# differential_evolution step 114: f(x)= 736.1568262985883
# differential_evolution step 115: f(x)= 736.1568262985883
# differential_evolution step 116: f(x)= 736.1568262985883
# differential_evolution step 117: f(x)= 736.1568262985883
# differential_evolution step 118: f(x)= 736.1568262985883
# differential_evolution step 119: f(x)= 736.1568262985883
# differential_evolution step 120: f(x)= 736.1568262985883
# differential_evolution step 121: f(x)= 736.1568262985883
# differential_evolution step 122: f(x)= 736.1568262985883
# differential_evolution step 123: f(x)= 736.1568262985883
# differential_evolution step 124: f(x)= 736.1568262985883
# differential_evolution step 125: f(x)= 736.1568262985883
# differential_evolution step 126: f(x)= 736.1568262985883
# differential_evolution step 127: f(x)= 735.581234224577
# differential_evolution step 128: f(x)= 735.581234224577
# differential_evolution step 129: f(x)= 735.581234224577
# differential_evolution step 130: f(x)= 735.581234224577
# differential_evolution step 131: f(x)= 735.581234224577
# differential_evolution step 132: f(x)= 735.581234224577
# differential_evolution step 133: f(x)= 735.581234224577
# differential_evolution step 134: f(x)= 735.5385254645454
# differential_evolution step 135: f(x)= 735.5385254645454
# differential_evolution step 136: f(x)= 735.5385254645454
# differential_evolution step 137: f(x)= 735.4455153718536
# differential_evolution step 138: f(x)= 735.4455153718536
# differential_evolution step 139: f(x)= 735.4455153718536
# differential_evolution step 140: f(x)= 735.4455153718536
# differential_evolution step 141: f(x)= 735.3600924946688
# differential_evolution step 142: f(x)= 735.3600924946688
# differential_evolution step 143: f(x)= 735.3600924946688
# differential_evolution step 144: f(x)= 735.2582973872592
# differential_evolution step 145: f(x)= 735.2582973872592
# differential_evolution step 146: f(x)= 735.2582973872592
# differential_evolution step 147: f(x)= 735.2582973872592
# differential_evolution step 148: f(x)= 735.1896510076317
# differential_evolution step 149: f(x)= 735.1896510076317
# differential_evolution step 150: f(x)= 735.1896510076317
# differential_evolution step 151: f(x)= 735.1896510076317
# differential_evolution step 152: f(x)= 735.1896510076317
# differential_evolution step 153: f(x)= 735.1896510076317
# differential_evolution step 154: f(x)= 735.1787652823892
# differential_evolution step 155: f(x)= 735.1787652823892
# differential_evolution step 156: f(x)= 735.1462888646357
# differential_evolution step 157: f(x)= 735.1462888646357
# differential_evolution step 158: f(x)= 735.1462888646357
# differential_evolution step 159: f(x)= 735.1462888646357
# differential_evolution step 160: f(x)= 734.9069570565064
# differential_evolution step 161: f(x)= 734.9069570565064
# differential_evolution step 162: f(x)= 734.9069570565064
# differential_evolution step 163: f(x)= 734.9069570565064
# differential_evolution step 164: f(x)= 734.9069570565064
# differential_evolution step 165: f(x)= 734.9069570565064
# differential_evolution step 166: f(x)= 734.9069570565064
# differential_evolution step 167: f(x)= 734.9069570565064
# differential_evolution step 168: f(x)= 734.9069570565064
# differential_evolution step 169: f(x)= 734.9069570565064
# differential_evolution step 170: f(x)= 734.9069570565064
# differential_evolution step 171: f(x)= 734.9069570565064
# differential_evolution step 172: f(x)= 734.9069570565064
# differential_evolution step 173: f(x)= 734.9069570565064
# differential_evolution step 174: f(x)= 734.9069570565064
# differential_evolution step 175: f(x)= 734.9069570565064
# differential_evolution step 176: f(x)= 734.9069570565064
# differential_evolution step 177: f(x)= 734.9069570565064
# differential_evolution step 178: f(x)= 734.9069570565064
# differential_evolution step 179: f(x)= 734.8313280814898
# differential_evolution step 180: f(x)= 734.8313280814898
# differential_evolution step 181: f(x)= 734.7776777476214
# differential_evolution step 182: f(x)= 734.7201249343656
# differential_evolution step 183: f(x)= 734.6925710229121
# differential_evolution step 184: f(x)= 734.6925710229121
# differential_evolution step 185: f(x)= 734.6925710229121
# differential_evolution step 186: f(x)= 734.6925710229121
# differential_evolution step 187: f(x)= 734.6925710229121
# differential_evolution step 188: f(x)= 734.6925710229121
# differential_evolution step 189: f(x)= 734.6741153523091
# differential_evolution step 190: f(x)= 734.6741153523091
# differential_evolution step 191: f(x)= 734.6741153523091
# differential_evolution step 192: f(x)= 734.6249527685621
# differential_evolution step 193: f(x)= 734.6249527685621
# differential_evolution step 194: f(x)= 734.6249527685621
# differential_evolution step 195: f(x)= 734.6249527685621
# differential_evolution step 196: f(x)= 734.6249527685621
# differential_evolution step 197: f(x)= 734.6249527685621
# differential_evolution step 198: f(x)= 734.6249527685621
# differential_evolution step 199: f(x)= 734.6249527685621
# differential_evolution step 200: f(x)= 734.5883465497674
# differential_evolution step 201: f(x)= 734.5883465497674
# differential_evolution step 202: f(x)= 734.5883465497674
# differential_evolution step 203: f(x)= 734.5883465497674
# differential_evolution step 204: f(x)= 734.5883465497674
# differential_evolution step 205: f(x)= 734.5883465497674
# differential_evolution step 206: f(x)= 734.5883465497674
# differential_evolution step 207: f(x)= 734.5883465497674
# differential_evolution step 208: f(x)= 734.5826563601242
# differential_evolution step 209: f(x)= 734.5741476944302
# differential_evolution step 210: f(x)= 734.5741476944302
# differential_evolution step 211: f(x)= 734.567318669302
# differential_evolution step 212: f(x)= 734.567318669302
# differential_evolution step 213: f(x)= 734.567318669302
# differential_evolution step 214: f(x)= 734.567318669302
# differential_evolution step 215: f(x)= 734.567318669302
# differential_evolution step 216: f(x)= 734.567318669302
# differential_evolution step 217: f(x)= 734.5626403132986
# differential_evolution step 218: f(x)= 734.5626403132986
# differential_evolution step 219: f(x)= 734.5626403132986
# differential_evolution step 220: f(x)= 734.5626403132986
# differential_evolution step 221: f(x)= 734.5560875391702
# differential_evolution step 222: f(x)= 734.5560875391702
# differential_evolution step 223: f(x)= 734.5560875391702
# differential_evolution step 224: f(x)= 734.5560875391702
# differential_evolution step 225: f(x)= 734.5560875391702
# differential_evolution step 226: f(x)= 734.5560875391702
# differential_evolution step 227: f(x)= 734.5560875391702
# differential_evolution step 228: f(x)= 734.5560875391702
# differential_evolution step 229: f(x)= 734.5560875391702
# differential_evolution step 230: f(x)= 734.5527431181564
# differential_evolution step 231: f(x)= 734.5527431181564
# differential_evolution step 232: f(x)= 734.5524728714438
# differential_evolution step 233: f(x)= 734.54309547417
# differential_evolution step 234: f(x)= 734.54309547417
# differential_evolution step 235: f(x)= 734.54309547417
# differential_evolution step 236: f(x)= 734.539935923575
# differential_evolution step 237: f(x)= 734.533415090873
# differential_evolution step 238: f(x)= 734.533415090873
# differential_evolution step 239: f(x)= 734.533415090873
# differential_evolution step 240: f(x)= 734.533415090873
# differential_evolution step 241: f(x)= 734.533415090873
# differential_evolution step 242: f(x)= 734.533415090873
# differential_evolution step 243: f(x)= 734.533415090873
# differential_evolution step 244: f(x)= 734.533415090873
# differential_evolution step 245: f(x)= 734.533415090873
# differential_evolution step 246: f(x)= 734.533415090873
# differential_evolution step 247: f(x)= 734.533415090873
# differential_evolution step 248: f(x)= 734.533415090873
# differential_evolution step 249: f(x)= 734.533415090873
# differential_evolution step 250: f(x)= 734.533415090873
# differential_evolution step 251: f(x)= 734.5293432508731
# differential_evolution step 252: f(x)= 734.5293432508731
# differential_evolution step 253: f(x)= 734.5293432508731
# differential_evolution step 254: f(x)= 734.5293432508731
# differential_evolution step 255: f(x)= 734.5293432508731
# differential_evolution step 256: f(x)= 734.5293432508731
# differential_evolution step 257: f(x)= 734.5293432508731
# differential_evolution step 258: f(x)= 734.526877831316
# differential_evolution step 259: f(x)= 734.526877831316
# differential_evolution step 260: f(x)= 734.526877831316
# differential_evolution step 261: f(x)= 734.526877831316
# differential_evolution step 262: f(x)= 734.526877831316
# differential_evolution step 263: f(x)= 734.526877831316
# differential_evolution step 264: f(x)= 734.526877831316
# differential_evolution step 265: f(x)= 734.526877831316
# differential_evolution step 266: f(x)= 734.526877831316
# differential_evolution step 267: f(x)= 734.5152744225795
# differential_evolution step 268: f(x)= 734.5152744225795
# differential_evolution step 269: f(x)= 734.5152744225795
# differential_evolution step 270: f(x)= 734.5152744225795
# differential_evolution step 271: f(x)= 734.5152744225795
# differential_evolution step 272: f(x)= 734.5152744225795
# differential_evolution step 273: f(x)= 734.5152744225795
# differential_evolution step 274: f(x)= 734.5152744225795
# differential_evolution step 275: f(x)= 734.5152744225795
# differential_evolution step 276: f(x)= 734.5152744225795
# differential_evolution step 277: f(x)= 734.5152744225795
# differential_evolution step 278: f(x)= 734.5152744225795
# differential_evolution step 279: f(x)= 734.5152744225795
# differential_evolution step 280: f(x)= 734.5152744225795
# differential_evolution step 281: f(x)= 734.5119279187151
# differential_evolution step 282: f(x)= 734.5119279187151
# differential_evolution step 283: f(x)= 734.5119279187151
# differential_evolution step 284: f(x)= 734.5119279187151
# differential_evolution step 285: f(x)= 734.5119279187151
# differential_evolution step 286: f(x)= 734.5119279187151
# differential_evolution step 287: f(x)= 734.5119279187151
# differential_evolution step 288: f(x)= 734.5119279187151
# differential_evolution step 289: f(x)= 734.5119279187151
# differential_evolution step 290: f(x)= 734.5119279187151
# differential_evolution step 291: f(x)= 734.5119279187151
# differential_evolution step 292: f(x)= 734.5119279187151
# differential_evolution step 293: f(x)= 734.5119279187151
# differential_evolution step 294: f(x)= 734.5119279187151
# differential_evolution step 295: f(x)= 734.5119279187151
# differential_evolution step 296: f(x)= 734.5119279187151
# differential_evolution step 297: f(x)= 734.5119279187151
# differential_evolution step 298: f(x)= 734.5119279187151
# differential_evolution step 299: f(x)= 734.5119279187151
# differential_evolution step 300: f(x)= 734.5119279187151
# differential_evolution step 301: f(x)= 734.5119279187151
# differential_evolution step 302: f(x)= 734.5119279187151
# differential_evolution step 303: f(x)= 734.5119279187151
# differential_evolution step 304: f(x)= 734.5095866481855
# differential_evolution step 305: f(x)= 734.5095866481855
# differential_evolution step 306: f(x)= 734.5095866481855
# differential_evolution step 307: f(x)= 734.5095866481855
# differential_evolution step 308: f(x)= 734.5095866481855
# differential_evolution step 309: f(x)= 734.5095866481855
# differential_evolution step 310: f(x)= 734.5095866481855
# differential_evolution step 311: f(x)= 734.5095866481855
# differential_evolution step 312: f(x)= 734.5095866481855
# differential_evolution step 313: f(x)= 734.5095866481855
# differential_evolution step 314: f(x)= 734.5095866481855
# differential_evolution step 315: f(x)= 734.5095866481855
# differential_evolution step 316: f(x)= 734.5095866481855
# differential_evolution step 317: f(x)= 734.5066243976503
# differential_evolution step 318: f(x)= 734.5066243976503
# differential_evolution step 319: f(x)= 734.5066243976503
# differential_evolution step 320: f(x)= 734.5064066005247
# differential_evolution step 321: f(x)= 734.5064066005247
# differential_evolution step 322: f(x)= 734.5064066005247
# differential_evolution step 323: f(x)= 734.5064066005247
# differential_evolution step 324: f(x)= 734.5052713174493
# differential_evolution step 325: f(x)= 734.5052713174493
# differential_evolution step 326: f(x)= 734.5052713174493
# differential_evolution step 327: f(x)= 734.5052713174493
# differential_evolution step 328: f(x)= 734.5052713174493
# differential_evolution step 329: f(x)= 734.5052713174493
# differential_evolution step 330: f(x)= 734.503992330213
# differential_evolution step 331: f(x)= 734.503992330213
# differential_evolution step 332: f(x)= 734.503992330213
# differential_evolution step 333: f(x)= 734.503992330213
# differential_evolution step 334: f(x)= 734.503992330213
# differential_evolution step 335: f(x)= 734.503992330213
# differential_evolution step 336: f(x)= 734.503992330213
# differential_evolution step 337: f(x)= 734.503365532319
# differential_evolution step 338: f(x)= 734.503365532319
# differential_evolution step 339: f(x)= 734.5032009480527
# differential_evolution step 340: f(x)= 734.5031567226131
# differential_evolution step 341: f(x)= 734.502339376022
# differential_evolution step 342: f(x)= 734.502339376022
# differential_evolution step 343: f(x)= 734.5021717647633
# differential_evolution step 344: f(x)= 734.5018523720865
# differential_evolution step 345: f(x)= 734.5018523720865
# differential_evolution step 346: f(x)= 734.5018523720865
# differential_evolution step 347: f(x)= 734.5014372912079
# differential_evolution step 348: f(x)= 734.5014372912079
# differential_evolution step 349: f(x)= 734.5014372912079
# differential_evolution step 350: f(x)= 734.5014372912079
# differential_evolution step 351: f(x)= 734.5013494050527
# differential_evolution step 352: f(x)= 734.5012148583966
# differential_evolution step 353: f(x)= 734.5012148583966
# differential_evolution step 354: f(x)= 734.5010852071965
# differential_evolution step 355: f(x)= 734.5010852071965
# differential_evolution step 356: f(x)= 734.5008488693439
# differential_evolution step 357: f(x)= 734.500164231379
# differential_evolution step 358: f(x)= 734.500164231379
# differential_evolution step 359: f(x)= 734.500164231379
# differential_evolution step 360: f(x)= 734.5001243216952
# differential_evolution step 361: f(x)= 734.5001243216952
# differential_evolution step 362: f(x)= 734.5001243216952
# differential_evolution step 363: f(x)= 734.4999281746929
# differential_evolution step 364: f(x)= 734.4999281746929
# differential_evolution step 365: f(x)= 734.4999281746929
# differential_evolution step 366: f(x)= 734.4999281746929
# differential_evolution step 367: f(x)= 734.4999281746929
# differential_evolution step 368: f(x)= 734.4998843724153
# differential_evolution step 369: f(x)= 734.4997433278445
# differential_evolution step 370: f(x)= 734.4997433278445
# differential_evolution step 371: f(x)= 734.4990904508877
# differential_evolution step 372: f(x)= 734.4990904508877
# differential_evolution step 373: f(x)= 734.4990904508877
# differential_evolution step 374: f(x)= 734.4990904508877
# differential_evolution step 375: f(x)= 734.4990904508877
# differential_evolution step 376: f(x)= 734.4990904508877
# differential_evolution step 377: f(x)= 734.4990904508877
# differential_evolution step 378: f(x)= 734.4990904508877
# differential_evolution step 379: f(x)= 734.4990904508877
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=43.8593, n=3.0232, x_0=38.3845
# Sérsic 2: I_e=0.9995, r_e=0.7275, n=2.3144, x_0=48.6459
# Sérsic 3: I_e=1.0000, r_e=13.0146, n=1.5275, x_0=80.5721
# Chi quadro minimo: 734.4989502701113
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HA, r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')

# %%
bounds_HA = [
    (0.5, 1.5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 5),  # n: da 0.1 a 10
    (35, 40),   # x_0: posizione da 0 a 100

    (0.5, 1.5),
    (0, 1),
    (0.1, 4),
    (45, 50),

    (0.5, 1.5),
    (0, 20),
    (0.1, 5),
    (80, 85)
]
lower_bounds, upper_bounds = zip(*bounds_HA)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(model_convolved, x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, radial_profile_error_HA,
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.0745, r_e=33.9201, n=3.0976, x_0=38.2614
# Sérsic 2: I_e=1.1522, r_e=0.7845, n=2.3562, x_0=48.4974
# Sérsic 3: I_e=1.3400, r_e=11.4632, n=1.3547, x_0=80.2973
# [4.33029125e-01 9.25799002e+00 3.29025607e-01 8.36837210e-02
#  8.19918530e+01 3.25770912e+01 2.39702827e+02 1.47054479e-01
#  7.45485970e-01 4.40133604e+00 3.99384009e-01 3.60318097e-01]
# 887.3891058231267

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-(seeing/2), x_0_HA[0]+(seeing/2)),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-(seeing/2), x_0_HA[1]+(seeing/2)),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-(seeing/2), x_0_HA[2]+(seeing/2))
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')

# %%
bounds
# Out:
# [(0, 1),
#  (0, 50),
#  (0.1, 10),
#  (37.269400000000005, 39.2534),
#  (0, 1),
#  (0, 50),
#  (0.1, 10),
#  (47.5054, 49.489399999999996),
#  (0, 1),
#  (0, 50),
#  (0.1, 10),
#  (79.3053, 81.28930000000001)]

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 866.8612081626796
# differential_evolution step 2: f(x)= 393.79264921954365
# differential_evolution step 3: f(x)= 393.79264921954365
# differential_evolution step 4: f(x)= 354.93576425745874
# differential_evolution step 5: f(x)= 264.95703404525864
# differential_evolution step 6: f(x)= 246.55533585251737
# differential_evolution step 7: f(x)= 246.55533585251737
# differential_evolution step 8: f(x)= 246.55533585251737
# differential_evolution step 9: f(x)= 246.55533585251737
# differential_evolution step 10: f(x)= 246.55533585251737
# differential_evolution step 11: f(x)= 240.79293120264998
# differential_evolution step 12: f(x)= 217.2958030353551
# differential_evolution step 13: f(x)= 217.2958030353551
# differential_evolution step 14: f(x)= 217.2958030353551
# differential_evolution step 15: f(x)= 217.2958030353551
# differential_evolution step 16: f(x)= 216.1122389528762
# differential_evolution step 17: f(x)= 216.1122389528762
# differential_evolution step 18: f(x)= 209.90032958989798
# differential_evolution step 19: f(x)= 204.13691818837128
# differential_evolution step 20: f(x)= 204.13691818837128
# differential_evolution step 21: f(x)= 200.7953993594699
# differential_evolution step 22: f(x)= 200.7953993594699
# differential_evolution step 23: f(x)= 185.91513716186498
# differential_evolution step 24: f(x)= 185.91513716186498
# differential_evolution step 25: f(x)= 185.91513716186498
# differential_evolution step 26: f(x)= 185.91513716186498
# differential_evolution step 27: f(x)= 185.91513716186498
# differential_evolution step 28: f(x)= 185.91513716186498
# differential_evolution step 29: f(x)= 185.91513716186498
# differential_evolution step 30: f(x)= 185.91513716186498
# differential_evolution step 31: f(x)= 180.9234656093204
# differential_evolution step 32: f(x)= 180.9234656093204
# differential_evolution step 33: f(x)= 180.9234656093204
# differential_evolution step 34: f(x)= 179.5995152567265
# differential_evolution step 35: f(x)= 179.5995152567265
# differential_evolution step 36: f(x)= 179.5995152567265
# differential_evolution step 37: f(x)= 179.5995152567265
# differential_evolution step 38: f(x)= 179.5995152567265
# differential_evolution step 39: f(x)= 179.5995152567265
# differential_evolution step 40: f(x)= 179.5995152567265
# differential_evolution step 41: f(x)= 179.5995152567265
# differential_evolution step 42: f(x)= 179.5995152567265
# differential_evolution step 43: f(x)= 179.5995152567265
# differential_evolution step 44: f(x)= 179.5995152567265
# differential_evolution step 45: f(x)= 179.5995152567265
# differential_evolution step 46: f(x)= 179.5995152567265
# differential_evolution step 47: f(x)= 179.5995152567265
# differential_evolution step 48: f(x)= 179.5995152567265
# differential_evolution step 49: f(x)= 179.5995152567265
# differential_evolution step 50: f(x)= 179.5995152567265
# differential_evolution step 51: f(x)= 179.5995152567265
# differential_evolution step 52: f(x)= 179.5995152567265
# differential_evolution step 53: f(x)= 179.5995152567265
# differential_evolution step 54: f(x)= 178.14565412416735
# differential_evolution step 55: f(x)= 178.14565412416735
# differential_evolution step 56: f(x)= 178.14565412416735
# differential_evolution step 57: f(x)= 178.14565412416735
# differential_evolution step 58: f(x)= 178.14565412416735
# differential_evolution step 59: f(x)= 178.14565412416735
# differential_evolution step 60: f(x)= 178.14565412416735
# differential_evolution step 61: f(x)= 178.14565412416735
# differential_evolution step 62: f(x)= 178.14565412416735
# differential_evolution step 63: f(x)= 178.14565412416735
# differential_evolution step 64: f(x)= 178.14565412416735
# differential_evolution step 65: f(x)= 178.14565412416735
# differential_evolution step 66: f(x)= 178.14565412416735
# differential_evolution step 67: f(x)= 176.52573663354042
# differential_evolution step 68: f(x)= 176.50125639980598
# differential_evolution step 69: f(x)= 176.29139174513443
# differential_evolution step 70: f(x)= 176.29139174513443
# differential_evolution step 71: f(x)= 175.53712515717683
# differential_evolution step 72: f(x)= 175.53712515717683
# differential_evolution step 73: f(x)= 175.53712515717683
# differential_evolution step 74: f(x)= 175.53712515717683
# differential_evolution step 75: f(x)= 175.53712515717683
# differential_evolution step 76: f(x)= 175.53712515717683
# differential_evolution step 77: f(x)= 175.53712515717683
# differential_evolution step 78: f(x)= 175.53712515717683
# differential_evolution step 79: f(x)= 175.53712515717683
# differential_evolution step 80: f(x)= 175.53712515717683
# differential_evolution step 81: f(x)= 175.53712515717683
# differential_evolution step 82: f(x)= 173.9611303712366
# differential_evolution step 83: f(x)= 172.48508294216126
# differential_evolution step 84: f(x)= 172.48508294216126
# differential_evolution step 85: f(x)= 172.48508294216126
# differential_evolution step 86: f(x)= 172.48508294216126
# differential_evolution step 87: f(x)= 172.1645952890735
# differential_evolution step 88: f(x)= 172.1645952890735
# differential_evolution step 89: f(x)= 172.1645952890735
# differential_evolution step 90: f(x)= 170.2819069202571
# differential_evolution step 91: f(x)= 170.2819069202571
# differential_evolution step 92: f(x)= 170.2819069202571
# differential_evolution step 93: f(x)= 170.2819069202571
# differential_evolution step 94: f(x)= 170.2819069202571
# differential_evolution step 95: f(x)= 170.2819069202571
# differential_evolution step 96: f(x)= 169.62868215489826
# differential_evolution step 97: f(x)= 169.62868215489826
# differential_evolution step 98: f(x)= 169.62868215489826
# differential_evolution step 99: f(x)= 169.62868215489826
# differential_evolution step 100: f(x)= 169.62868215489826
# differential_evolution step 101: f(x)= 169.62868215489826
# differential_evolution step 102: f(x)= 169.62868215489826
# differential_evolution step 103: f(x)= 169.62868215489826
# differential_evolution step 104: f(x)= 169.62868215489826
# differential_evolution step 105: f(x)= 169.62868215489826
# differential_evolution step 106: f(x)= 169.62868215489826
# differential_evolution step 107: f(x)= 169.62868215489826
# differential_evolution step 108: f(x)= 169.62868215489826
# differential_evolution step 109: f(x)= 169.62868215489826
# differential_evolution step 110: f(x)= 169.62868215489826
# differential_evolution step 111: f(x)= 169.62868215489826
# differential_evolution step 112: f(x)= 169.62868215489826
# differential_evolution step 113: f(x)= 169.62868215489826
# differential_evolution step 114: f(x)= 169.37454885041967
# differential_evolution step 115: f(x)= 169.37454885041967
# differential_evolution step 116: f(x)= 169.37454885041967
# differential_evolution step 117: f(x)= 169.37454885041967
# differential_evolution step 118: f(x)= 169.37454885041967
# differential_evolution step 119: f(x)= 169.22303378891624
# differential_evolution step 120: f(x)= 169.10876538521566
# differential_evolution step 121: f(x)= 169.0812744320458
# differential_evolution step 122: f(x)= 169.0812744320458
# differential_evolution step 123: f(x)= 169.0812744320458
# differential_evolution step 124: f(x)= 169.0812744320458
# differential_evolution step 125: f(x)= 169.0812744320458
# differential_evolution step 126: f(x)= 169.0812744320458
# differential_evolution step 127: f(x)= 168.7907367477863
# differential_evolution step 128: f(x)= 168.7907367477863
# differential_evolution step 129: f(x)= 168.7907367477863
# differential_evolution step 130: f(x)= 168.7907367477863
# differential_evolution step 131: f(x)= 168.7907367477863
# differential_evolution step 132: f(x)= 168.7456416757401
# differential_evolution step 133: f(x)= 168.7456416757401
# differential_evolution step 134: f(x)= 168.32690557171264
# differential_evolution step 135: f(x)= 168.32690557171264
# differential_evolution step 136: f(x)= 168.32690557171264
# differential_evolution step 137: f(x)= 168.32690557171264
# differential_evolution step 138: f(x)= 168.32690557171264
# differential_evolution step 139: f(x)= 168.32690557171264
# differential_evolution step 140: f(x)= 168.32690557171264
# differential_evolution step 141: f(x)= 168.32690557171264
# differential_evolution step 142: f(x)= 168.32690557171264
# differential_evolution step 143: f(x)= 168.30599618491436
# differential_evolution step 144: f(x)= 168.30599618491436
# differential_evolution step 145: f(x)= 168.30599618491436
# differential_evolution step 146: f(x)= 168.30599618491436
# differential_evolution step 147: f(x)= 168.30599618491436
# differential_evolution step 148: f(x)= 168.30599618491436
# differential_evolution step 149: f(x)= 168.30599618491436
# differential_evolution step 150: f(x)= 168.30599618491436
# differential_evolution step 151: f(x)= 168.30599618491436
# differential_evolution step 152: f(x)= 168.30599618491436
# differential_evolution step 153: f(x)= 168.30599618491436
# differential_evolution step 154: f(x)= 168.30599618491436
# differential_evolution step 155: f(x)= 168.30599618491436
# differential_evolution step 156: f(x)= 168.30599618491436
# differential_evolution step 157: f(x)= 168.30599618491436
# differential_evolution step 158: f(x)= 168.27466870600037
# differential_evolution step 159: f(x)= 168.21033136045196
# differential_evolution step 160: f(x)= 168.21033136045196
# differential_evolution step 161: f(x)= 168.0388050501156
# differential_evolution step 162: f(x)= 167.97067296581065
# differential_evolution step 163: f(x)= 167.97067296581065
# differential_evolution step 164: f(x)= 167.9521450446963
# differential_evolution step 165: f(x)= 167.9521450446963
# differential_evolution step 166: f(x)= 167.93554503588288
# differential_evolution step 167: f(x)= 167.93554503588288
# differential_evolution step 168: f(x)= 167.93554503588288
# differential_evolution step 169: f(x)= 167.79264953896313
# differential_evolution step 170: f(x)= 167.79264953896313
# differential_evolution step 171: f(x)= 167.79264953896313
# differential_evolution step 172: f(x)= 167.79264953896313
# differential_evolution step 173: f(x)= 167.79264953896313
# differential_evolution step 174: f(x)= 167.71941896217504
# differential_evolution step 175: f(x)= 167.71941896217504
# differential_evolution step 176: f(x)= 167.71941896217504
# differential_evolution step 177: f(x)= 167.7011232909751
# differential_evolution step 178: f(x)= 167.7011232909751
# differential_evolution step 179: f(x)= 167.7011232909751
# differential_evolution step 180: f(x)= 167.7011232909751
# differential_evolution step 181: f(x)= 167.7011232909751
# differential_evolution step 182: f(x)= 167.7011232909751
# differential_evolution step 183: f(x)= 167.62280876981262
# differential_evolution step 184: f(x)= 167.62280876981262
# differential_evolution step 185: f(x)= 167.62280876981262
# differential_evolution step 186: f(x)= 167.62280876981262
# differential_evolution step 187: f(x)= 167.62280876981262
# differential_evolution step 188: f(x)= 167.62280876981262
# differential_evolution step 189: f(x)= 167.60417755786523
# differential_evolution step 190: f(x)= 167.60417755786523
# differential_evolution step 191: f(x)= 167.60417755786523
# differential_evolution step 192: f(x)= 167.60417755786523
# differential_evolution step 193: f(x)= 167.60417755786523
# differential_evolution step 194: f(x)= 167.60417755786523
# differential_evolution step 195: f(x)= 167.60417755786523
# differential_evolution step 196: f(x)= 167.55426926001365
# differential_evolution step 197: f(x)= 167.55426926001365
# differential_evolution step 198: f(x)= 167.55426926001365
# differential_evolution step 199: f(x)= 167.55426926001365
# differential_evolution step 200: f(x)= 167.55426926001365
# differential_evolution step 201: f(x)= 167.55426926001365
# differential_evolution step 202: f(x)= 167.55426926001365
# differential_evolution step 203: f(x)= 167.55426926001365
# differential_evolution step 204: f(x)= 167.55426926001365
# differential_evolution step 205: f(x)= 167.55426926001365
# differential_evolution step 206: f(x)= 167.55426926001365
# differential_evolution step 207: f(x)= 167.55426926001365
# differential_evolution step 208: f(x)= 167.55426926001365
# differential_evolution step 209: f(x)= 167.55426926001365
# differential_evolution step 210: f(x)= 167.55426926001365
# differential_evolution step 211: f(x)= 167.55426926001365
# differential_evolution step 212: f(x)= 167.55426926001365
# differential_evolution step 213: f(x)= 167.55426926001365
# differential_evolution step 214: f(x)= 167.55426926001365
# differential_evolution step 215: f(x)= 167.54373256566643
# differential_evolution step 216: f(x)= 167.54013535455337
# differential_evolution step 217: f(x)= 167.54013535455337
# differential_evolution step 218: f(x)= 167.54013535455337
# differential_evolution step 219: f(x)= 167.53819039228577
# differential_evolution step 220: f(x)= 167.53819039228577
# differential_evolution step 221: f(x)= 167.51833172587862
# differential_evolution step 222: f(x)= 167.51785422692095
# differential_evolution step 223: f(x)= 167.51785422692095
# differential_evolution step 224: f(x)= 167.5172815214778
# differential_evolution step 225: f(x)= 167.5172815214778
# differential_evolution step 226: f(x)= 167.5172815214778
# differential_evolution step 227: f(x)= 167.5172815214778
# differential_evolution step 228: f(x)= 167.5172815214778
# differential_evolution step 229: f(x)= 167.5172815214778
# differential_evolution step 230: f(x)= 167.5172815214778
# differential_evolution step 231: f(x)= 167.5172815214778
# differential_evolution step 232: f(x)= 167.5172815214778
# differential_evolution step 233: f(x)= 167.5172815214778
# differential_evolution step 234: f(x)= 167.5172815214778
# differential_evolution step 235: f(x)= 167.5172815214778
# differential_evolution step 236: f(x)= 167.5172815214778
# differential_evolution step 237: f(x)= 167.5172815214778
# differential_evolution step 238: f(x)= 167.509879294155
# differential_evolution step 239: f(x)= 167.505698375445
# differential_evolution step 240: f(x)= 167.50412612941471
# differential_evolution step 241: f(x)= 167.50412612941471
# differential_evolution step 242: f(x)= 167.50412612941471
# differential_evolution step 243: f(x)= 167.50412612941471
# differential_evolution step 244: f(x)= 167.50412612941471
# differential_evolution step 245: f(x)= 167.50039230354966
# differential_evolution step 246: f(x)= 167.50039230354966
# differential_evolution step 247: f(x)= 167.4990665036168
# differential_evolution step 248: f(x)= 167.4990665036168
# differential_evolution step 249: f(x)= 167.4990665036168
# differential_evolution step 250: f(x)= 167.4990665036168
# differential_evolution step 251: f(x)= 167.4990665036168
# differential_evolution step 252: f(x)= 167.4990665036168
# differential_evolution step 253: f(x)= 167.49891703410734
# differential_evolution step 254: f(x)= 167.49891703410734
# differential_evolution step 255: f(x)= 167.49891703410734
# differential_evolution step 256: f(x)= 167.4975780167053
# differential_evolution step 257: f(x)= 167.4975780167053
# differential_evolution step 258: f(x)= 167.4975780167053
# differential_evolution step 259: f(x)= 167.4975780167053
# differential_evolution step 260: f(x)= 167.4975780167053
# differential_evolution step 261: f(x)= 167.4975780167053
# differential_evolution step 262: f(x)= 167.4975780167053
# differential_evolution step 263: f(x)= 167.4975780167053
# differential_evolution step 264: f(x)= 167.4975780167053
# differential_evolution step 265: f(x)= 167.4975780167053
# differential_evolution step 266: f(x)= 167.49456916495467
# differential_evolution step 267: f(x)= 167.49456916495467
# differential_evolution step 268: f(x)= 167.49456916495467
# differential_evolution step 269: f(x)= 167.49259907600506
# differential_evolution step 270: f(x)= 167.49259907600506
# differential_evolution step 271: f(x)= 167.49259907600506
# differential_evolution step 272: f(x)= 167.49259907600506
# differential_evolution step 273: f(x)= 167.49259907600506
# differential_evolution step 274: f(x)= 167.49259907600506
# differential_evolution step 275: f(x)= 167.49259907600506
# differential_evolution step 276: f(x)= 167.49122999819173
# differential_evolution step 277: f(x)= 167.48936906277405
# differential_evolution step 278: f(x)= 167.48936906277405
# differential_evolution step 279: f(x)= 167.4860601490941
# differential_evolution step 280: f(x)= 167.4860601490941
# differential_evolution step 281: f(x)= 167.4860601490941
# differential_evolution step 282: f(x)= 167.4860601490941
# differential_evolution step 283: f(x)= 167.4860601490941
# differential_evolution step 284: f(x)= 167.4860601490941
# differential_evolution step 285: f(x)= 167.4860601490941
# differential_evolution step 286: f(x)= 167.4860601490941
# differential_evolution step 287: f(x)= 167.4860601490941
# differential_evolution step 288: f(x)= 167.4860601490941
# differential_evolution step 289: f(x)= 167.4860601490941
# differential_evolution step 290: f(x)= 167.4860601490941
# differential_evolution step 291: f(x)= 167.4860601490941
# differential_evolution step 292: f(x)= 167.4860601490941
# differential_evolution step 293: f(x)= 167.4860601490941
# differential_evolution step 294: f(x)= 167.4860601490941
# differential_evolution step 295: f(x)= 167.48360149969324
# differential_evolution step 296: f(x)= 167.48303558927762
# differential_evolution step 297: f(x)= 167.48303558927762
# differential_evolution step 298: f(x)= 167.48303558927762
# differential_evolution step 299: f(x)= 167.48303558927762
# differential_evolution step 300: f(x)= 167.48303558927762
# differential_evolution step 301: f(x)= 167.48303558927762
# differential_evolution step 302: f(x)= 167.48303558927762
# differential_evolution step 303: f(x)= 167.48303558927762
# differential_evolution step 304: f(x)= 167.48303558927762
# differential_evolution step 305: f(x)= 167.48303558927762
# differential_evolution step 306: f(x)= 167.48303558927762
# differential_evolution step 307: f(x)= 167.48303558927762
# differential_evolution step 308: f(x)= 167.48303558927762
# differential_evolution step 309: f(x)= 167.48303558927762
# differential_evolution step 310: f(x)= 167.48303558927762
# differential_evolution step 311: f(x)= 167.48303558927762
# differential_evolution step 312: f(x)= 167.48221229584175
# differential_evolution step 313: f(x)= 167.48221229584175
# differential_evolution step 314: f(x)= 167.48221229584175
# differential_evolution step 315: f(x)= 167.48221229584175
# differential_evolution step 316: f(x)= 167.48221229584175
# differential_evolution step 317: f(x)= 167.48221229584175
# differential_evolution step 318: f(x)= 167.48221229584175
# differential_evolution step 319: f(x)= 167.48221229584175
# differential_evolution step 320: f(x)= 167.48221229584175
# differential_evolution step 321: f(x)= 167.4815819951553
# differential_evolution step 322: f(x)= 167.4815819951553
# differential_evolution step 323: f(x)= 167.4815819951553
# differential_evolution step 324: f(x)= 167.4815819951553
# differential_evolution step 325: f(x)= 167.4815819951553
# differential_evolution step 326: f(x)= 167.4815819951553
# differential_evolution step 327: f(x)= 167.4815819951553
# differential_evolution step 328: f(x)= 167.4815819951553
# differential_evolution step 329: f(x)= 167.4815039250843
# differential_evolution step 330: f(x)= 167.4815039250843
# differential_evolution step 331: f(x)= 167.4815039250843
# differential_evolution step 332: f(x)= 167.4815039250843
# differential_evolution step 333: f(x)= 167.4815039250843
# differential_evolution step 334: f(x)= 167.4815039250843
# differential_evolution step 335: f(x)= 167.4815039250843
# differential_evolution step 336: f(x)= 167.4815039250843
# differential_evolution step 337: f(x)= 167.4815039250843
# differential_evolution step 338: f(x)= 167.4815039250843
# differential_evolution step 339: f(x)= 167.4815039250843
# differential_evolution step 340: f(x)= 167.4815039250843
# differential_evolution step 341: f(x)= 167.48141455604508
# differential_evolution step 342: f(x)= 167.48141455604508
# differential_evolution step 343: f(x)= 167.48141455604508
# differential_evolution step 344: f(x)= 167.48141455604508
# differential_evolution step 345: f(x)= 167.48141455604508
# differential_evolution step 346: f(x)= 167.48141455604508
# differential_evolution step 347: f(x)= 167.48141455604508
# differential_evolution step 348: f(x)= 167.48108798133848
# differential_evolution step 349: f(x)= 167.48108798133848
# differential_evolution step 350: f(x)= 167.48108798133848
# differential_evolution step 351: f(x)= 167.4808815455141
# differential_evolution step 352: f(x)= 167.48056131659104
# differential_evolution step 353: f(x)= 167.48056131659104
# differential_evolution step 354: f(x)= 167.48056131659104
# differential_evolution step 355: f(x)= 167.48056131659104
# differential_evolution step 356: f(x)= 167.48056131659104
# differential_evolution step 357: f(x)= 167.48052453424128
# differential_evolution step 358: f(x)= 167.48052453424128
# differential_evolution step 359: f(x)= 167.48052453424128
# differential_evolution step 360: f(x)= 167.48052453424128
# differential_evolution step 361: f(x)= 167.48052453424128
# differential_evolution step 362: f(x)= 167.48050476477346
# differential_evolution step 363: f(x)= 167.48050476477346
# differential_evolution step 364: f(x)= 167.48050476477346
# differential_evolution step 365: f(x)= 167.48050476477346
# differential_evolution step 366: f(x)= 167.48050476477346
# differential_evolution step 367: f(x)= 167.48050476477346
# differential_evolution step 368: f(x)= 167.48050476477346
# differential_evolution step 369: f(x)= 167.48050476477346
# differential_evolution step 370: f(x)= 167.48050476477346
# differential_evolution step 371: f(x)= 167.48050476477346
# differential_evolution step 372: f(x)= 167.48050476477346
# differential_evolution step 373: f(x)= 167.48050476477346
# differential_evolution step 374: f(x)= 167.48050476477346
# differential_evolution step 375: f(x)= 167.48050476477346
# differential_evolution step 376: f(x)= 167.48050476477346
# differential_evolution step 377: f(x)= 167.48050476477346
# differential_evolution step 378: f(x)= 167.48050476477346
# differential_evolution step 379: f(x)= 167.48050476477346
# differential_evolution step 380: f(x)= 167.48050476477346
# differential_evolution step 381: f(x)= 167.48050476477346
# differential_evolution step 382: f(x)= 167.48050476477346
# differential_evolution step 383: f(x)= 167.48050476477346
# differential_evolution step 384: f(x)= 167.4804865522066
# differential_evolution step 385: f(x)= 167.4804468299013
# differential_evolution step 386: f(x)= 167.4804468299013
# differential_evolution step 387: f(x)= 167.4804388390717
# differential_evolution step 388: f(x)= 167.480363458687
# differential_evolution step 389: f(x)= 167.480363458687
# differential_evolution step 390: f(x)= 167.480363458687
# differential_evolution step 391: f(x)= 167.480363458687
# differential_evolution step 392: f(x)= 167.480363458687
# differential_evolution step 393: f(x)= 167.480363458687
# differential_evolution step 394: f(x)= 167.480363458687
# differential_evolution step 395: f(x)= 167.480363458687
# differential_evolution step 396: f(x)= 167.480363458687
# differential_evolution step 397: f(x)= 167.480363458687
# differential_evolution step 398: f(x)= 167.480363458687
# differential_evolution step 399: f(x)= 167.480363458687
# differential_evolution step 400: f(x)= 167.480363458687
# differential_evolution step 401: f(x)= 167.480363458687
# differential_evolution step 402: f(x)= 167.480363458687
# differential_evolution step 403: f(x)= 167.480363458687
# differential_evolution step 404: f(x)= 167.48034630841556
# differential_evolution step 405: f(x)= 167.48032741225705
# differential_evolution step 406: f(x)= 167.48013653315
# differential_evolution step 407: f(x)= 167.48013653315
# differential_evolution step 408: f(x)= 167.48013653315
# differential_evolution step 409: f(x)= 167.48013653315
# differential_evolution step 410: f(x)= 167.48013653315
# differential_evolution step 411: f(x)= 167.48013653315
# differential_evolution step 412: f(x)= 167.48013653315
# differential_evolution step 413: f(x)= 167.48013653315
# differential_evolution step 414: f(x)= 167.48013653315
# differential_evolution step 415: f(x)= 167.48013653315
# differential_evolution step 416: f(x)= 167.48013653315
# differential_evolution step 417: f(x)= 167.48013653315
# differential_evolution step 418: f(x)= 167.48013653315
# differential_evolution step 419: f(x)= 167.48013653315
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=19.9784, n=2.7577, x_0=38.1869
# Sérsic 2: I_e=1.0000, r_e=1.1063, n=1.3598, x_0=48.6462
# Sérsic 3: I_e=0.2789, r_e=14.3728, n=2.0045, x_0=80.9280
# Chi quadro minimo: 167.48010082996353
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HB, r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')

# %%
bounds_new = [
    (0.5, 1.5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 5),  # n: da 0.1 a 10
    (35, 40),   # x_0: posizione da 0 a 100

    (0.5, 1.5),
    (0, 3),
    (0.1, 4),
    (45, 50),

    (0, 1.5),
    (0, 25),
    (0.1, 5),
    (76, 85)
]
lower_bounds, upper_bounds = zip(*bounds_new)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(model_convolved, x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB, bounds = bounds_list)

chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, radial_profile_error_HB,
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Sérsic 1: I_e=1.2925, r_e=14.4179, n=2.6548, x_0=38.0126
# Sérsic 2: I_e=1.4953, r_e=1.7183, n=0.7846, x_0=48.8389
# Sérsic 3: I_e=0.1670, r_e=23.7499, n=2.3238, x_0=80.8042
# [4.97072232e-01 3.85632789e+00 3.12421007e-01 6.68814127e-02
#  2.35395073e+00 1.34669651e+00 1.25995273e+00 3.48809421e-01
#  4.77124225e-01 4.77255164e+01 2.55582660e+00 3.72958162e-02]
# 215.6685286932786

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 394.25566869314855
# differential_evolution step 2: f(x)= 394.25566869314855
# differential_evolution step 3: f(x)= 126.96167939783267
# differential_evolution step 4: f(x)= 126.96167939783267
# differential_evolution step 5: f(x)= 126.96167939783267
# differential_evolution step 6: f(x)= 126.96167939783267
# differential_evolution step 7: f(x)= 126.96167939783267
# differential_evolution step 8: f(x)= 126.96167939783267
# differential_evolution step 9: f(x)= 126.96167939783267
# differential_evolution step 10: f(x)= 126.96167939783267
# differential_evolution step 11: f(x)= 126.96167939783267
# differential_evolution step 12: f(x)= 126.96167939783267
# differential_evolution step 13: f(x)= 126.96167939783267
# differential_evolution step 14: f(x)= 126.96167939783267
# differential_evolution step 15: f(x)= 126.96167939783267
# differential_evolution step 16: f(x)= 126.96167939783267
# differential_evolution step 17: f(x)= 126.96167939783267
# differential_evolution step 18: f(x)= 126.96167939783267
# differential_evolution step 19: f(x)= 126.96167939783267
# differential_evolution step 20: f(x)= 126.3139462840821
# differential_evolution step 21: f(x)= 126.3139462840821
# differential_evolution step 22: f(x)= 126.3139462840821
# differential_evolution step 23: f(x)= 109.71378908931307
# differential_evolution step 24: f(x)= 106.5226219243573
# differential_evolution step 25: f(x)= 106.5226219243573
# differential_evolution step 26: f(x)= 106.5226219243573
# differential_evolution step 27: f(x)= 106.5226219243573
# differential_evolution step 28: f(x)= 106.5226219243573
# differential_evolution step 29: f(x)= 95.56822943409983
# differential_evolution step 30: f(x)= 95.56822943409983
# differential_evolution step 31: f(x)= 95.56822943409983
# differential_evolution step 32: f(x)= 94.1735285001204
# differential_evolution step 33: f(x)= 94.1735285001204
# differential_evolution step 34: f(x)= 85.00338340761036
# differential_evolution step 35: f(x)= 79.44946212048072
# differential_evolution step 36: f(x)= 79.44946212048072
# differential_evolution step 37: f(x)= 79.44946212048072
# differential_evolution step 38: f(x)= 79.44946212048072
# differential_evolution step 39: f(x)= 79.44946212048072
# differential_evolution step 40: f(x)= 79.44946212048072
# differential_evolution step 41: f(x)= 79.44946212048072
# differential_evolution step 42: f(x)= 79.44946212048072
# differential_evolution step 43: f(x)= 75.0174799201611
# differential_evolution step 44: f(x)= 75.0174799201611
# differential_evolution step 45: f(x)= 75.0174799201611
# differential_evolution step 46: f(x)= 75.0174799201611
# differential_evolution step 47: f(x)= 75.0174799201611
# differential_evolution step 48: f(x)= 75.0174799201611
# differential_evolution step 49: f(x)= 75.0174799201611
# differential_evolution step 50: f(x)= 75.0174799201611
# differential_evolution step 51: f(x)= 75.0174799201611
# differential_evolution step 52: f(x)= 75.0174799201611
# differential_evolution step 53: f(x)= 75.0174799201611
# differential_evolution step 54: f(x)= 75.0174799201611
# differential_evolution step 55: f(x)= 75.0174799201611
# differential_evolution step 56: f(x)= 75.0174799201611
# differential_evolution step 57: f(x)= 75.0174799201611
# differential_evolution step 58: f(x)= 75.0174799201611
# differential_evolution step 59: f(x)= 75.0174799201611
# differential_evolution step 60: f(x)= 73.21781346757615
# differential_evolution step 61: f(x)= 73.21781346757615
# differential_evolution step 62: f(x)= 73.21781346757615
# differential_evolution step 63: f(x)= 73.21781346757615
# differential_evolution step 64: f(x)= 73.21781346757615
# differential_evolution step 65: f(x)= 73.21781346757615
# differential_evolution step 66: f(x)= 73.21781346757615
# differential_evolution step 67: f(x)= 73.21781346757615
# differential_evolution step 68: f(x)= 73.21781346757615
# differential_evolution step 69: f(x)= 71.96879754781276
# differential_evolution step 70: f(x)= 71.96879754781276
# differential_evolution step 71: f(x)= 71.96879754781276
# differential_evolution step 72: f(x)= 71.96879754781276
# differential_evolution step 73: f(x)= 71.96879754781276
# differential_evolution step 74: f(x)= 71.96879754781276
# differential_evolution step 75: f(x)= 71.96879754781276
# differential_evolution step 76: f(x)= 71.96879754781276
# differential_evolution step 77: f(x)= 71.96879754781276
# differential_evolution step 78: f(x)= 71.96879754781276
# differential_evolution step 79: f(x)= 71.96879754781276
# differential_evolution step 80: f(x)= 71.96879754781276
# differential_evolution step 81: f(x)= 71.76325051120818
# differential_evolution step 82: f(x)= 71.76325051120818
# differential_evolution step 83: f(x)= 71.76325051120818
# differential_evolution step 84: f(x)= 71.55606019131409
# differential_evolution step 85: f(x)= 71.55606019131409
# differential_evolution step 86: f(x)= 71.30513882933441
# differential_evolution step 87: f(x)= 71.30513882933441
# differential_evolution step 88: f(x)= 71.30513882933441
# differential_evolution step 89: f(x)= 71.30513882933441
# differential_evolution step 90: f(x)= 69.29773505828746
# differential_evolution step 91: f(x)= 68.97693515856089
# differential_evolution step 92: f(x)= 68.97693515856089
# differential_evolution step 93: f(x)= 68.97693515856089
# differential_evolution step 94: f(x)= 68.97693515856089
# differential_evolution step 95: f(x)= 68.91841622665989
# differential_evolution step 96: f(x)= 68.91841622665989
# differential_evolution step 97: f(x)= 68.91841622665989
# differential_evolution step 98: f(x)= 67.80301792434037
# differential_evolution step 99: f(x)= 67.80301792434037
# differential_evolution step 100: f(x)= 67.69632796843968
# differential_evolution step 101: f(x)= 67.69632796843968
# differential_evolution step 102: f(x)= 67.69632796843968
# differential_evolution step 103: f(x)= 67.69632796843968
# differential_evolution step 104: f(x)= 67.69632796843968
# differential_evolution step 105: f(x)= 67.69632796843968
# differential_evolution step 106: f(x)= 67.69632796843968
# differential_evolution step 107: f(x)= 67.69632796843968
# differential_evolution step 108: f(x)= 67.69632796843968
# differential_evolution step 109: f(x)= 67.69632796843968
# differential_evolution step 110: f(x)= 67.69632796843968
# differential_evolution step 111: f(x)= 67.69632796843968
# differential_evolution step 112: f(x)= 67.69632796843968
# differential_evolution step 113: f(x)= 67.69632796843968
# differential_evolution step 114: f(x)= 67.69632796843968
# differential_evolution step 115: f(x)= 67.69632796843968
# differential_evolution step 116: f(x)= 67.69632796843968
# differential_evolution step 117: f(x)= 67.69632796843968
# differential_evolution step 118: f(x)= 67.46799116962988
# differential_evolution step 119: f(x)= 67.46799116962988
# differential_evolution step 120: f(x)= 67.46799116962988
# differential_evolution step 121: f(x)= 66.45227420567879
# differential_evolution step 122: f(x)= 66.45227420567879
# differential_evolution step 123: f(x)= 66.45227420567879
# differential_evolution step 124: f(x)= 66.45227420567879
# differential_evolution step 125: f(x)= 66.45227420567879
# differential_evolution step 126: f(x)= 66.45227420567879
# differential_evolution step 127: f(x)= 66.45227420567879
# differential_evolution step 128: f(x)= 66.45227420567879
# differential_evolution step 129: f(x)= 66.45227420567879
# differential_evolution step 130: f(x)= 66.45227420567879
# differential_evolution step 131: f(x)= 66.45227420567879
# differential_evolution step 132: f(x)= 66.43061583249347
# differential_evolution step 133: f(x)= 65.97525556937343
# differential_evolution step 134: f(x)= 65.97525556937343
# differential_evolution step 135: f(x)= 65.97525556937343
# differential_evolution step 136: f(x)= 65.71058820431301
# differential_evolution step 137: f(x)= 65.71058820431301
# differential_evolution step 138: f(x)= 65.71058820431301
# differential_evolution step 139: f(x)= 65.71058820431301
# differential_evolution step 140: f(x)= 65.71058820431301
# differential_evolution step 141: f(x)= 65.71058820431301
# differential_evolution step 142: f(x)= 65.5390789447465
# differential_evolution step 143: f(x)= 65.5390789447465
# differential_evolution step 144: f(x)= 65.5390789447465
# differential_evolution step 145: f(x)= 65.5390789447465
# differential_evolution step 146: f(x)= 65.5390789447465
# differential_evolution step 147: f(x)= 65.5390789447465
# differential_evolution step 148: f(x)= 65.5390789447465
# differential_evolution step 149: f(x)= 65.5390789447465
# differential_evolution step 150: f(x)= 65.5390789447465
# differential_evolution step 151: f(x)= 65.5390789447465
# differential_evolution step 152: f(x)= 65.3107104606593
# differential_evolution step 153: f(x)= 65.3107104606593
# differential_evolution step 154: f(x)= 65.17592246613397
# differential_evolution step 155: f(x)= 65.17592246613397
# differential_evolution step 156: f(x)= 65.17592246613397
# differential_evolution step 157: f(x)= 65.17592246613397
# differential_evolution step 158: f(x)= 65.17592246613397
# differential_evolution step 159: f(x)= 65.17592246613397
# differential_evolution step 160: f(x)= 65.17592246613397
# differential_evolution step 161: f(x)= 65.17592246613397
# differential_evolution step 162: f(x)= 65.17592246613397
# differential_evolution step 163: f(x)= 65.17592246613397
# differential_evolution step 164: f(x)= 65.17592246613397
# differential_evolution step 165: f(x)= 65.17592246613397
# differential_evolution step 166: f(x)= 65.17592246613397
# differential_evolution step 167: f(x)= 65.17592246613397
# differential_evolution step 168: f(x)= 65.17592246613397
# differential_evolution step 169: f(x)= 65.17592246613397
# differential_evolution step 170: f(x)= 65.17592246613397
# differential_evolution step 171: f(x)= 65.12784981888684
# differential_evolution step 172: f(x)= 65.12784981888684
# differential_evolution step 173: f(x)= 65.12784981888684
# differential_evolution step 174: f(x)= 65.12784981888684
# differential_evolution step 175: f(x)= 65.12784981888684
# differential_evolution step 176: f(x)= 65.12784981888684
# differential_evolution step 177: f(x)= 64.97389809194655
# differential_evolution step 178: f(x)= 64.866773971444
# differential_evolution step 179: f(x)= 64.866773971444
# differential_evolution step 180: f(x)= 64.866773971444
# differential_evolution step 181: f(x)= 64.866773971444
# differential_evolution step 182: f(x)= 64.866773971444
# differential_evolution step 183: f(x)= 64.866773971444
# differential_evolution step 184: f(x)= 64.866773971444
# differential_evolution step 185: f(x)= 64.8235528885622
# differential_evolution step 186: f(x)= 64.8235528885622
# differential_evolution step 187: f(x)= 64.8235528885622
# differential_evolution step 188: f(x)= 64.81573783227338
# differential_evolution step 189: f(x)= 64.81573783227338
# differential_evolution step 190: f(x)= 64.81573783227338
# differential_evolution step 191: f(x)= 64.81573783227338
# differential_evolution step 192: f(x)= 64.81573783227338
# differential_evolution step 193: f(x)= 64.81573783227338
# differential_evolution step 194: f(x)= 64.70100427899312
# differential_evolution step 195: f(x)= 64.53729193465543
# differential_evolution step 196: f(x)= 64.53729193465543
# differential_evolution step 197: f(x)= 64.53729193465543
# differential_evolution step 198: f(x)= 64.53729193465543
# differential_evolution step 199: f(x)= 64.53729193465543
# differential_evolution step 200: f(x)= 64.53729193465543
# differential_evolution step 201: f(x)= 64.53729193465543
# differential_evolution step 202: f(x)= 64.53729193465543
# differential_evolution step 203: f(x)= 64.53729193465543
# differential_evolution step 204: f(x)= 64.53729193465543
# differential_evolution step 205: f(x)= 64.53729193465543
# differential_evolution step 206: f(x)= 64.52991176182863
# differential_evolution step 207: f(x)= 64.52991176182863
# differential_evolution step 208: f(x)= 64.52288732166971
# differential_evolution step 209: f(x)= 64.52288732166971
# differential_evolution step 210: f(x)= 64.52288732166971
# differential_evolution step 211: f(x)= 64.52288732166971
# differential_evolution step 212: f(x)= 64.51199171204392
# differential_evolution step 213: f(x)= 64.51199171204392
# differential_evolution step 214: f(x)= 64.41341467494303
# differential_evolution step 215: f(x)= 64.41341467494303
# differential_evolution step 216: f(x)= 64.22431949718359
# differential_evolution step 217: f(x)= 64.22431949718359
# differential_evolution step 218: f(x)= 64.22431949718359
# differential_evolution step 219: f(x)= 64.20188143522671
# differential_evolution step 220: f(x)= 64.20188143522671
# differential_evolution step 221: f(x)= 64.20188143522671
# differential_evolution step 222: f(x)= 64.20188143522671
# differential_evolution step 223: f(x)= 64.18421310718956
# differential_evolution step 224: f(x)= 64.18421310718956
# differential_evolution step 225: f(x)= 64.18421310718956
# differential_evolution step 226: f(x)= 64.1202144234073
# differential_evolution step 227: f(x)= 64.07473446044162
# differential_evolution step 228: f(x)= 64.07473446044162
# differential_evolution step 229: f(x)= 64.07473446044162
# differential_evolution step 230: f(x)= 63.94283798627057
# differential_evolution step 231: f(x)= 63.94283798627057
# differential_evolution step 232: f(x)= 63.94283798627057
# differential_evolution step 233: f(x)= 63.94283798627057
# differential_evolution step 234: f(x)= 63.94283798627057
# differential_evolution step 235: f(x)= 63.94283798627057
# differential_evolution step 236: f(x)= 63.94283798627057
# differential_evolution step 237: f(x)= 63.94283798627057
# differential_evolution step 238: f(x)= 63.94283798627057
# differential_evolution step 239: f(x)= 63.94283798627057
# differential_evolution step 240: f(x)= 63.94283798627057
# differential_evolution step 241: f(x)= 63.94283798627057
# differential_evolution step 242: f(x)= 63.94283798627057
# differential_evolution step 243: f(x)= 63.899984411116336
# differential_evolution step 244: f(x)= 63.899984411116336
# differential_evolution step 245: f(x)= 63.899984411116336
# differential_evolution step 246: f(x)= 63.899984411116336
# differential_evolution step 247: f(x)= 63.899984411116336
# differential_evolution step 248: f(x)= 63.871228970960246
# differential_evolution step 249: f(x)= 63.871228970960246
# differential_evolution step 250: f(x)= 63.871228970960246
# differential_evolution step 251: f(x)= 63.871228970960246
# differential_evolution step 252: f(x)= 63.871228970960246
# differential_evolution step 253: f(x)= 63.871228970960246
# differential_evolution step 254: f(x)= 63.86804295865121
# differential_evolution step 255: f(x)= 63.86804295865121
# differential_evolution step 256: f(x)= 63.86804295865121
# differential_evolution step 257: f(x)= 63.86804295865121
# differential_evolution step 258: f(x)= 63.86804295865121
# differential_evolution step 259: f(x)= 63.86804295865121
# differential_evolution step 260: f(x)= 63.864729512715186
# differential_evolution step 261: f(x)= 63.847366300185676
# differential_evolution step 262: f(x)= 63.847366300185676
# differential_evolution step 263: f(x)= 63.83094387317204
# differential_evolution step 264: f(x)= 63.83094387317204
# differential_evolution step 265: f(x)= 63.83094387317204
# differential_evolution step 266: f(x)= 63.83094387317204
# differential_evolution step 267: f(x)= 63.82034791504083
# differential_evolution step 268: f(x)= 63.82034791504083
# differential_evolution step 269: f(x)= 63.82034791504083
# differential_evolution step 270: f(x)= 63.82034791504083
# differential_evolution step 271: f(x)= 63.81406441766055
# differential_evolution step 272: f(x)= 63.81406441766055
# differential_evolution step 273: f(x)= 63.81406441766055
# differential_evolution step 274: f(x)= 63.81406441766055
# differential_evolution step 275: f(x)= 63.81406441766055
# differential_evolution step 276: f(x)= 63.81406441766055
# differential_evolution step 277: f(x)= 63.81406441766055
# differential_evolution step 278: f(x)= 63.81406441766055
# differential_evolution step 279: f(x)= 63.81406441766055
# differential_evolution step 280: f(x)= 63.81406441766055
# differential_evolution step 281: f(x)= 63.81406441766055
# differential_evolution step 282: f(x)= 63.81406441766055
# differential_evolution step 283: f(x)= 63.81406441766055
# differential_evolution step 284: f(x)= 63.785659990573485
# differential_evolution step 285: f(x)= 63.785659990573485
# differential_evolution step 286: f(x)= 63.785659990573485
# differential_evolution step 287: f(x)= 63.760810916733305
# differential_evolution step 288: f(x)= 63.760810916733305
# differential_evolution step 289: f(x)= 63.760810916733305
# differential_evolution step 290: f(x)= 63.760810916733305
# differential_evolution step 291: f(x)= 63.760810916733305
# differential_evolution step 292: f(x)= 63.75046914913007
# differential_evolution step 293: f(x)= 63.75046914913007
# differential_evolution step 294: f(x)= 63.75046914913007
# differential_evolution step 295: f(x)= 63.75046914913007
# differential_evolution step 296: f(x)= 63.75046914913007
# differential_evolution step 297: f(x)= 63.73916112061172
# differential_evolution step 298: f(x)= 63.73916112061172
# differential_evolution step 299: f(x)= 63.735385252511094
# differential_evolution step 300: f(x)= 63.735385252511094
# differential_evolution step 301: f(x)= 63.734502168640844
# differential_evolution step 302: f(x)= 63.734502168640844
# differential_evolution step 303: f(x)= 63.734502168640844
# differential_evolution step 304: f(x)= 63.734502168640844
# differential_evolution step 305: f(x)= 63.734502168640844
# differential_evolution step 306: f(x)= 63.734502168640844
# differential_evolution step 307: f(x)= 63.73284306167838
# differential_evolution step 308: f(x)= 63.73284306167838
# differential_evolution step 309: f(x)= 63.73284306167838
# differential_evolution step 310: f(x)= 63.730038143326496
# differential_evolution step 311: f(x)= 63.730038143326496
# differential_evolution step 312: f(x)= 63.730038143326496
# differential_evolution step 313: f(x)= 63.729441553699225
# differential_evolution step 314: f(x)= 63.729441553699225
# differential_evolution step 315: f(x)= 63.729441553699225
# differential_evolution step 316: f(x)= 63.729441553699225
# differential_evolution step 317: f(x)= 63.725245397107805
# differential_evolution step 318: f(x)= 63.725245397107805
# differential_evolution step 319: f(x)= 63.725245397107805
# differential_evolution step 320: f(x)= 63.7181410457977
# differential_evolution step 321: f(x)= 63.7181410457977
# differential_evolution step 322: f(x)= 63.7181410457977
# differential_evolution step 323: f(x)= 63.716739567681444
# differential_evolution step 324: f(x)= 63.716739567681444
# differential_evolution step 325: f(x)= 63.716739567681444
# differential_evolution step 326: f(x)= 63.716739567681444
# differential_evolution step 327: f(x)= 63.716739567681444
# differential_evolution step 328: f(x)= 63.716739567681444
# differential_evolution step 329: f(x)= 63.716739567681444
# differential_evolution step 330: f(x)= 63.716739567681444
# differential_evolution step 331: f(x)= 63.71514885951432
# differential_evolution step 332: f(x)= 63.70910484330586
# differential_evolution step 333: f(x)= 63.70910484330586
# differential_evolution step 334: f(x)= 63.70910484330586
# differential_evolution step 335: f(x)= 63.70910484330586
# differential_evolution step 336: f(x)= 63.70910484330586
# differential_evolution step 337: f(x)= 63.70910484330586
# differential_evolution step 338: f(x)= 63.70910484330586
# differential_evolution step 339: f(x)= 63.70910484330586
# differential_evolution step 340: f(x)= 63.70910484330586
# differential_evolution step 341: f(x)= 63.70910484330586
# differential_evolution step 342: f(x)= 63.70910484330586
# differential_evolution step 343: f(x)= 63.70910484330586
# differential_evolution step 344: f(x)= 63.70910484330586
# differential_evolution step 345: f(x)= 63.70910484330586
# differential_evolution step 346: f(x)= 63.70910484330586
# differential_evolution step 347: f(x)= 63.70807981368775
# differential_evolution step 348: f(x)= 63.70807981368775
# differential_evolution step 349: f(x)= 63.70807981368775
# differential_evolution step 350: f(x)= 63.70807981368775
# differential_evolution step 351: f(x)= 63.705974942843355
# differential_evolution step 352: f(x)= 63.705974942843355
# differential_evolution step 353: f(x)= 63.705974942843355
# differential_evolution step 354: f(x)= 63.70559517873904
# differential_evolution step 355: f(x)= 63.70559517873904
# differential_evolution step 356: f(x)= 63.70559517873904
# differential_evolution step 357: f(x)= 63.70559517873904
# differential_evolution step 358: f(x)= 63.70559517873904
# differential_evolution step 359: f(x)= 63.70559517873904
# differential_evolution step 360: f(x)= 63.70559517873904
# differential_evolution step 361: f(x)= 63.70559517873904
# differential_evolution step 362: f(x)= 63.704842181779036
# differential_evolution step 363: f(x)= 63.704842181779036
# differential_evolution step 364: f(x)= 63.704756092863605
# differential_evolution step 365: f(x)= 63.704756092863605
# differential_evolution step 366: f(x)= 63.704756092863605
# differential_evolution step 367: f(x)= 63.704756092863605
# differential_evolution step 368: f(x)= 63.704756092863605
# differential_evolution step 369: f(x)= 63.70428822372845
# differential_evolution step 370: f(x)= 63.70428822372845
# differential_evolution step 371: f(x)= 63.70428822372845
# differential_evolution step 372: f(x)= 63.70428822372845
# differential_evolution step 373: f(x)= 63.70428822372845
# differential_evolution step 374: f(x)= 63.70428822372845
# differential_evolution step 375: f(x)= 63.70428822372845
# differential_evolution step 376: f(x)= 63.70428822372845
# differential_evolution step 377: f(x)= 63.7042551897534
# differential_evolution step 378: f(x)= 63.7042551897534
# differential_evolution step 379: f(x)= 63.7042551897534
# differential_evolution step 380: f(x)= 63.7042551897534
# differential_evolution step 381: f(x)= 63.7042551897534
# differential_evolution step 382: f(x)= 63.7042551897534
# differential_evolution step 383: f(x)= 63.703731580008565
# differential_evolution step 384: f(x)= 63.703731580008565
# differential_evolution step 385: f(x)= 63.70355966903247
# differential_evolution step 386: f(x)= 63.70355966903247
# differential_evolution step 387: f(x)= 63.70355966903247
# differential_evolution step 388: f(x)= 63.70355966903247
# differential_evolution step 389: f(x)= 63.70355966903247
# differential_evolution step 390: f(x)= 63.70355966903247
# differential_evolution step 391: f(x)= 63.70349578488391
# differential_evolution step 392: f(x)= 63.702752683628056
# differential_evolution step 393: f(x)= 63.702752683628056
# differential_evolution step 394: f(x)= 63.702752683628056
# differential_evolution step 395: f(x)= 63.702752683628056
# differential_evolution step 396: f(x)= 63.702752683628056
# differential_evolution step 397: f(x)= 63.702752683628056
# differential_evolution step 398: f(x)= 63.702752683628056
# differential_evolution step 399: f(x)= 63.702752683628056
# differential_evolution step 400: f(x)= 63.702752683628056
# differential_evolution step 401: f(x)= 63.702752683628056
# differential_evolution step 402: f(x)= 63.702752683628056
# differential_evolution step 403: f(x)= 63.70257291377685
# differential_evolution step 404: f(x)= 63.70257291377685
# differential_evolution step 405: f(x)= 63.70249665807871
# differential_evolution step 406: f(x)= 63.70249665807871
# differential_evolution step 407: f(x)= 63.70249665807871
# differential_evolution step 408: f(x)= 63.70236680299211
# differential_evolution step 409: f(x)= 63.7022194439721
# differential_evolution step 410: f(x)= 63.7022194439721
# differential_evolution step 411: f(x)= 63.7022194439721
# differential_evolution step 412: f(x)= 63.7022194439721
# differential_evolution step 413: f(x)= 63.7022194439721
# differential_evolution step 414: f(x)= 63.7022194439721
# differential_evolution step 415: f(x)= 63.7022194439721
# differential_evolution step 416: f(x)= 63.7022194439721
# differential_evolution step 417: f(x)= 63.7022194439721
# differential_evolution step 418: f(x)= 63.7022194439721
# differential_evolution step 419: f(x)= 63.7022194439721
# differential_evolution step 420: f(x)= 63.7022194439721
# differential_evolution step 421: f(x)= 63.7022194439721
# differential_evolution step 422: f(x)= 63.702167273518036
# differential_evolution step 423: f(x)= 63.702167273518036
# differential_evolution step 424: f(x)= 63.702167273518036
# differential_evolution step 425: f(x)= 63.702167273518036
# differential_evolution step 426: f(x)= 63.702164987400806
# differential_evolution step 427: f(x)= 63.702164987400806
# differential_evolution step 428: f(x)= 63.702164987400806
# differential_evolution step 429: f(x)= 63.702164987400806
# differential_evolution step 430: f(x)= 63.70213400609144
# differential_evolution step 431: f(x)= 63.70213265253922
# differential_evolution step 432: f(x)= 63.70213265253922
# differential_evolution step 433: f(x)= 63.70213265253922
# differential_evolution step 434: f(x)= 63.702083432061194
# differential_evolution step 435: f(x)= 63.702083432061194
# differential_evolution step 436: f(x)= 63.702083432061194
# differential_evolution step 437: f(x)= 63.702083432061194
# differential_evolution step 438: f(x)= 63.702083432061194
# differential_evolution step 439: f(x)= 63.702035246480555
# differential_evolution step 440: f(x)= 63.702035246480555
# differential_evolution step 441: f(x)= 63.70183744755471
# differential_evolution step 442: f(x)= 63.70183744755471
# differential_evolution step 443: f(x)= 63.70183744755471
# differential_evolution step 444: f(x)= 63.70183744755471
# differential_evolution step 445: f(x)= 63.70183744755471
# differential_evolution step 446: f(x)= 63.70183744755471
# differential_evolution step 447: f(x)= 63.70183744755471
# differential_evolution step 448: f(x)= 63.701821284971736
# differential_evolution step 449: f(x)= 63.701821284971736
# differential_evolution step 450: f(x)= 63.701821284971736
# differential_evolution step 451: f(x)= 63.701821284971736
# differential_evolution step 452: f(x)= 63.701821284971736
# differential_evolution step 453: f(x)= 63.701821284971736
# differential_evolution step 454: f(x)= 63.701821284971736
# differential_evolution step 455: f(x)= 63.701821284971736
# differential_evolution step 456: f(x)= 63.701821284971736
# differential_evolution step 457: f(x)= 63.701821284971736
# differential_evolution step 458: f(x)= 63.701821284971736
# differential_evolution step 459: f(x)= 63.701821284971736
# differential_evolution step 460: f(x)= 63.701821284971736
# differential_evolution step 461: f(x)= 63.701821284971736
# differential_evolution step 462: f(x)= 63.701821284971736
# differential_evolution step 463: f(x)= 63.701821284971736
# differential_evolution step 464: f(x)= 63.701821284971736
# differential_evolution step 465: f(x)= 63.701821284971736
# differential_evolution step 466: f(x)= 63.701821284971736
# differential_evolution step 467: f(x)= 63.701821284971736
# differential_evolution step 468: f(x)= 63.701821284971736
# differential_evolution step 469: f(x)= 63.701821284971736
# differential_evolution step 470: f(x)= 63.70181257702726
# differential_evolution step 471: f(x)= 63.70181257702726
# differential_evolution step 472: f(x)= 63.70181257702726
# differential_evolution step 473: f(x)= 63.70181257702726
# differential_evolution step 474: f(x)= 63.70181194136935
# differential_evolution step 475: f(x)= 63.701753069917196
# differential_evolution step 476: f(x)= 63.701753069917196
# differential_evolution step 477: f(x)= 63.701753069917196
# differential_evolution step 478: f(x)= 63.701753069917196
# differential_evolution step 479: f(x)= 63.701753069917196
# differential_evolution step 480: f(x)= 63.701753069917196
# differential_evolution step 481: f(x)= 63.701753069917196
# differential_evolution step 482: f(x)= 63.701753069917196
# differential_evolution step 483: f(x)= 63.701753069917196
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=21.5894, n=2.3903, x_0=38.4077
# Sérsic 2: I_e=1.0000, r_e=1.6849, n=1.4169, x_0=48.6025
# Sérsic 3: I_e=0.1731, r_e=28.7984, n=2.1442, x_0=80.8537
# Chi quadro minimo: 63.70171032336462
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII, r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(model_convolved, x_axes, radial_profile_NII, p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)

chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII,
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Sérsic 1: I_e=0.8266, r_e=23.0846, n=2.5635, x_0=38.2629
# Sérsic 2: I_e=1.0000, r_e=2.2514, n=1.2991, x_0=48.6751
# Sérsic 3: I_e=0.1527, r_e=30.6935, n=2.2383, x_0=80.7162
# [ 0.22891639  4.56169577  0.21786508  0.07072592  1.63244269  2.13651219
#   1.35152772  0.22223163  0.17594516 28.59172239  0.80110108  0.24590014]
# 201.0921588600794

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 58.14056421131519
# differential_evolution step 2: f(x)= 58.14056421131519
# differential_evolution step 3: f(x)= 58.14056421131519
# differential_evolution step 4: f(x)= 58.14056421131519
# differential_evolution step 5: f(x)= 58.14056421131519
# differential_evolution step 6: f(x)= 58.14056421131519
# differential_evolution step 7: f(x)= 37.718168070078995
# differential_evolution step 8: f(x)= 37.718168070078995
# differential_evolution step 9: f(x)= 32.65552128884191
# differential_evolution step 10: f(x)= 32.65552128884191
# differential_evolution step 11: f(x)= 28.591162808394273
# differential_evolution step 12: f(x)= 28.591162808394273
# differential_evolution step 13: f(x)= 26.640685862422046
# differential_evolution step 14: f(x)= 25.133563987969964
# differential_evolution step 15: f(x)= 16.252883027064303
# differential_evolution step 16: f(x)= 14.937871127700083
# differential_evolution step 17: f(x)= 14.937871127700083
# differential_evolution step 18: f(x)= 14.937871127700083
# differential_evolution step 19: f(x)= 14.937871127700083
# differential_evolution step 20: f(x)= 14.937871127700083
# differential_evolution step 21: f(x)= 14.937871127700083
# differential_evolution step 22: f(x)= 14.937871127700083
# differential_evolution step 23: f(x)= 14.937871127700083
# differential_evolution step 24: f(x)= 14.937871127700083
# differential_evolution step 25: f(x)= 14.937871127700083
# differential_evolution step 26: f(x)= 14.937871127700083
# differential_evolution step 27: f(x)= 14.937871127700083
# differential_evolution step 28: f(x)= 14.937871127700083
# differential_evolution step 29: f(x)= 14.937871127700083
# differential_evolution step 30: f(x)= 14.937871127700083
# differential_evolution step 31: f(x)= 14.937871127700083
# differential_evolution step 32: f(x)= 14.937871127700083
# differential_evolution step 33: f(x)= 14.937871127700083
# differential_evolution step 34: f(x)= 14.937871127700083
# differential_evolution step 35: f(x)= 14.937871127700083
# differential_evolution step 36: f(x)= 14.464179564071149
# differential_evolution step 37: f(x)= 13.12518329602441
# differential_evolution step 38: f(x)= 13.12518329602441
# differential_evolution step 39: f(x)= 13.12518329602441
# differential_evolution step 40: f(x)= 13.12518329602441
# differential_evolution step 41: f(x)= 12.747116175185681
# differential_evolution step 42: f(x)= 12.747116175185681
# differential_evolution step 43: f(x)= 12.747116175185681
# differential_evolution step 44: f(x)= 12.747116175185681
# differential_evolution step 45: f(x)= 12.747116175185681
# differential_evolution step 46: f(x)= 12.747116175185681
# differential_evolution step 47: f(x)= 12.612518298631539
# differential_evolution step 48: f(x)= 12.612518298631539
# differential_evolution step 49: f(x)= 12.612518298631539
# differential_evolution step 50: f(x)= 12.612518298631539
# differential_evolution step 51: f(x)= 12.612518298631539
# differential_evolution step 52: f(x)= 12.612518298631539
# differential_evolution step 53: f(x)= 12.595242678577808
# differential_evolution step 54: f(x)= 12.595242678577808
# differential_evolution step 55: f(x)= 11.62332448169696
# differential_evolution step 56: f(x)= 10.888599620984202
# differential_evolution step 57: f(x)= 10.888599620984202
# differential_evolution step 58: f(x)= 10.888599620984202
# differential_evolution step 59: f(x)= 10.888599620984202
# differential_evolution step 60: f(x)= 10.888599620984202
# differential_evolution step 61: f(x)= 10.888599620984202
# differential_evolution step 62: f(x)= 10.888599620984202
# differential_evolution step 63: f(x)= 10.679484835871055
# differential_evolution step 64: f(x)= 10.679484835871055
# differential_evolution step 65: f(x)= 10.679484835871055
# differential_evolution step 66: f(x)= 10.679484835871055
# differential_evolution step 67: f(x)= 10.679484835871055
# differential_evolution step 68: f(x)= 10.456569352884278
# differential_evolution step 69: f(x)= 10.456569352884278
# differential_evolution step 70: f(x)= 10.456569352884278
# differential_evolution step 71: f(x)= 10.456569352884278
# differential_evolution step 72: f(x)= 10.456569352884278
# differential_evolution step 73: f(x)= 10.456569352884278
# differential_evolution step 74: f(x)= 10.456569352884278
# differential_evolution step 75: f(x)= 10.456569352884278
# differential_evolution step 76: f(x)= 10.456569352884278
# differential_evolution step 77: f(x)= 10.341835750025227
# differential_evolution step 78: f(x)= 10.341835750025227
# differential_evolution step 79: f(x)= 10.248400342865182
# differential_evolution step 80: f(x)= 10.248400342865182
# differential_evolution step 81: f(x)= 10.248400342865182
# differential_evolution step 82: f(x)= 10.248400342865182
# differential_evolution step 83: f(x)= 10.248400342865182
# differential_evolution step 84: f(x)= 10.04928775519315
# differential_evolution step 85: f(x)= 10.04928775519315
# differential_evolution step 86: f(x)= 10.04928775519315
# differential_evolution step 87: f(x)= 10.04928775519315
# differential_evolution step 88: f(x)= 10.023602537630142
# differential_evolution step 89: f(x)= 10.023602537630142
# differential_evolution step 90: f(x)= 10.023602537630142
# differential_evolution step 91: f(x)= 10.023602537630142
# differential_evolution step 92: f(x)= 10.023602537630142
# differential_evolution step 93: f(x)= 10.023602537630142
# differential_evolution step 94: f(x)= 10.023602537630142
# differential_evolution step 95: f(x)= 10.023602537630142
# differential_evolution step 96: f(x)= 10.012553735304978
# differential_evolution step 97: f(x)= 10.012553735304978
# differential_evolution step 98: f(x)= 10.012553735304978
# differential_evolution step 99: f(x)= 10.012553735304978
# differential_evolution step 100: f(x)= 10.012553735304978
# differential_evolution step 101: f(x)= 10.012553735304978
# differential_evolution step 102: f(x)= 10.006519062256638
# differential_evolution step 103: f(x)= 9.988904491950066
# differential_evolution step 104: f(x)= 9.929399044885745
# differential_evolution step 105: f(x)= 9.929399044885745
# differential_evolution step 106: f(x)= 9.808287388481993
# differential_evolution step 107: f(x)= 9.808287388481993
# differential_evolution step 108: f(x)= 9.808287388481993
# differential_evolution step 109: f(x)= 9.808287388481993
# differential_evolution step 110: f(x)= 9.808287388481993
# differential_evolution step 111: f(x)= 9.808287388481993
# differential_evolution step 112: f(x)= 9.808287388481993
# differential_evolution step 113: f(x)= 9.808287388481993
# differential_evolution step 114: f(x)= 9.808287388481993
# differential_evolution step 115: f(x)= 9.808287388481993
# differential_evolution step 116: f(x)= 9.808287388481993
# differential_evolution step 117: f(x)= 9.808287388481993
# differential_evolution step 118: f(x)= 9.808287388481993
# differential_evolution step 119: f(x)= 9.808287388481993
# differential_evolution step 120: f(x)= 9.808287388481993
# differential_evolution step 121: f(x)= 9.808287388481993
# differential_evolution step 122: f(x)= 9.808287388481993
# differential_evolution step 123: f(x)= 9.808287388481993
# differential_evolution step 124: f(x)= 9.808287388481993
# differential_evolution step 125: f(x)= 9.808287388481993
# differential_evolution step 126: f(x)= 9.704258921916121
# differential_evolution step 127: f(x)= 9.701901470089103
# differential_evolution step 128: f(x)= 9.701901470089103
# differential_evolution step 129: f(x)= 9.701901470089103
# differential_evolution step 130: f(x)= 9.701901470089103
# differential_evolution step 131: f(x)= 9.646524951137437
# differential_evolution step 132: f(x)= 9.646524951137437
# differential_evolution step 133: f(x)= 9.641806849212047
# differential_evolution step 134: f(x)= 9.641806849212047
# differential_evolution step 135: f(x)= 9.641806849212047
# differential_evolution step 136: f(x)= 9.585700784124631
# differential_evolution step 137: f(x)= 9.585700784124631
# differential_evolution step 138: f(x)= 9.585700784124631
# differential_evolution step 139: f(x)= 9.585700784124631
# differential_evolution step 140: f(x)= 9.585700784124631
# differential_evolution step 141: f(x)= 9.585700784124631
# differential_evolution step 142: f(x)= 9.585700784124631
# differential_evolution step 143: f(x)= 9.585700784124631
# differential_evolution step 144: f(x)= 9.585700784124631
# differential_evolution step 145: f(x)= 9.585700784124631
# differential_evolution step 146: f(x)= 9.585700784124631
# differential_evolution step 147: f(x)= 9.585700784124631
# differential_evolution step 148: f(x)= 9.585700784124631
# differential_evolution step 149: f(x)= 9.585700784124631
# differential_evolution step 150: f(x)= 9.585700784124631
# differential_evolution step 151: f(x)= 9.585700784124631
# differential_evolution step 152: f(x)= 9.585700784124631
# differential_evolution step 153: f(x)= 9.585700784124631
# differential_evolution step 154: f(x)= 9.585700784124631
# differential_evolution step 155: f(x)= 9.585700784124631
# differential_evolution step 156: f(x)= 9.585700784124631
# differential_evolution step 157: f(x)= 9.585700784124631
# differential_evolution step 158: f(x)= 9.585700784124631
# differential_evolution step 159: f(x)= 9.57640085959628
# differential_evolution step 160: f(x)= 9.57640085959628
# differential_evolution step 161: f(x)= 9.57640085959628
# differential_evolution step 162: f(x)= 9.57640085959628
# differential_evolution step 163: f(x)= 9.569039880628168
# differential_evolution step 164: f(x)= 9.569039880628168
# differential_evolution step 165: f(x)= 9.569039880628168
# differential_evolution step 166: f(x)= 9.569039880628168
# differential_evolution step 167: f(x)= 9.569039880628168
# differential_evolution step 168: f(x)= 9.569039880628168
# differential_evolution step 169: f(x)= 9.569039880628168
# differential_evolution step 170: f(x)= 9.569039880628168
# differential_evolution step 171: f(x)= 9.565789476196173
# differential_evolution step 172: f(x)= 9.565789476196173
# differential_evolution step 173: f(x)= 9.531662633181943
# differential_evolution step 174: f(x)= 9.51453523455518
# differential_evolution step 175: f(x)= 9.51453523455518
# differential_evolution step 176: f(x)= 9.51453523455518
# differential_evolution step 177: f(x)= 9.51453523455518
# differential_evolution step 178: f(x)= 9.51453523455518
# differential_evolution step 179: f(x)= 9.51453523455518
# differential_evolution step 180: f(x)= 9.51453523455518
# differential_evolution step 181: f(x)= 9.51453523455518
# differential_evolution step 182: f(x)= 9.511353124979552
# differential_evolution step 183: f(x)= 9.511353124979552
# differential_evolution step 184: f(x)= 9.507430195397514
# differential_evolution step 185: f(x)= 9.507430195397514
# differential_evolution step 186: f(x)= 9.507430195397514
# differential_evolution step 187: f(x)= 9.507430195397514
# differential_evolution step 188: f(x)= 9.507430195397514
# differential_evolution step 189: f(x)= 9.489094861213294
# differential_evolution step 190: f(x)= 9.489094861213294
# differential_evolution step 191: f(x)= 9.489094861213294
# differential_evolution step 192: f(x)= 9.489094861213294
# differential_evolution step 193: f(x)= 9.45676131490971
# differential_evolution step 194: f(x)= 9.45676131490971
# differential_evolution step 195: f(x)= 9.45676131490971
# differential_evolution step 196: f(x)= 9.45676131490971
# differential_evolution step 197: f(x)= 9.45676131490971
# differential_evolution step 198: f(x)= 9.45676131490971
# differential_evolution step 199: f(x)= 9.45676131490971
# differential_evolution step 200: f(x)= 9.45676131490971
# differential_evolution step 201: f(x)= 9.45676131490971
# differential_evolution step 202: f(x)= 9.450005629566697
# differential_evolution step 203: f(x)= 9.450005629566697
# differential_evolution step 204: f(x)= 9.450005629566697
# differential_evolution step 205: f(x)= 9.450005629566697
# differential_evolution step 206: f(x)= 9.450005629566697
# differential_evolution step 207: f(x)= 9.450005629566697
# differential_evolution step 208: f(x)= 9.450005629566697
# differential_evolution step 209: f(x)= 9.450005629566697
# differential_evolution step 210: f(x)= 9.450005629566697
# differential_evolution step 211: f(x)= 9.450005629566697
# differential_evolution step 212: f(x)= 9.450005629566697
# differential_evolution step 213: f(x)= 9.450005629566697
# differential_evolution step 214: f(x)= 9.450005629566697
# differential_evolution step 215: f(x)= 9.450005629566697
# differential_evolution step 216: f(x)= 9.450005629566697
# differential_evolution step 217: f(x)= 9.450005629566697
# differential_evolution step 218: f(x)= 9.450005629566697
# differential_evolution step 219: f(x)= 9.450005629566697
# differential_evolution step 220: f(x)= 9.450005629566697
# differential_evolution step 221: f(x)= 9.450005629566697
# differential_evolution step 222: f(x)= 9.450005629566697
# differential_evolution step 223: f(x)= 9.450005629566697
# differential_evolution step 224: f(x)= 9.450005629566697
# differential_evolution step 225: f(x)= 9.433647195444841
# differential_evolution step 226: f(x)= 9.433647195444841
# differential_evolution step 227: f(x)= 9.418837069991383
# differential_evolution step 228: f(x)= 9.418837069991383
# differential_evolution step 229: f(x)= 9.418837069991383
# differential_evolution step 230: f(x)= 9.418837069991383
# differential_evolution step 231: f(x)= 9.418837069991383
# differential_evolution step 232: f(x)= 9.418837069991383
# differential_evolution step 233: f(x)= 9.418837069991383
# differential_evolution step 234: f(x)= 9.41784881417257
# differential_evolution step 235: f(x)= 9.41784881417257
# differential_evolution step 236: f(x)= 9.415298350549499
# differential_evolution step 237: f(x)= 9.415298350549499
# differential_evolution step 238: f(x)= 9.415298350549499
# differential_evolution step 239: f(x)= 9.415298350549499
# differential_evolution step 240: f(x)= 9.415298350549499
# differential_evolution step 241: f(x)= 9.415298350549499
# differential_evolution step 242: f(x)= 9.415298350549499
# differential_evolution step 243: f(x)= 9.415298350549499
# differential_evolution step 244: f(x)= 9.403843626046706
# differential_evolution step 245: f(x)= 9.403843626046706
# differential_evolution step 246: f(x)= 9.403843626046706
# differential_evolution step 247: f(x)= 9.403843626046706
# differential_evolution step 248: f(x)= 9.403843626046706
# differential_evolution step 249: f(x)= 9.403843626046706
# differential_evolution step 250: f(x)= 9.403843626046706
# differential_evolution step 251: f(x)= 9.403843626046706
# differential_evolution step 252: f(x)= 9.403843626046706
# differential_evolution step 253: f(x)= 9.403843626046706
# differential_evolution step 254: f(x)= 9.403843626046706
# differential_evolution step 255: f(x)= 9.403843626046706
# differential_evolution step 256: f(x)= 9.403843626046706
# differential_evolution step 257: f(x)= 9.403843626046706
# differential_evolution step 258: f(x)= 9.403843626046706
# differential_evolution step 259: f(x)= 9.403843626046706
# differential_evolution step 260: f(x)= 9.401330434678362
# differential_evolution step 261: f(x)= 9.401330434678362
# differential_evolution step 262: f(x)= 9.39153758151987
# differential_evolution step 263: f(x)= 9.39153758151987
# differential_evolution step 264: f(x)= 9.39153758151987
# differential_evolution step 265: f(x)= 9.39153758151987
# differential_evolution step 266: f(x)= 9.39153758151987
# differential_evolution step 267: f(x)= 9.39153758151987
# differential_evolution step 268: f(x)= 9.39153758151987
# differential_evolution step 269: f(x)= 9.39153758151987
# differential_evolution step 270: f(x)= 9.39153758151987
# differential_evolution step 271: f(x)= 9.39153758151987
# differential_evolution step 272: f(x)= 9.39153758151987
# differential_evolution step 273: f(x)= 9.389587847800895
# differential_evolution step 274: f(x)= 9.389587847800895
# differential_evolution step 275: f(x)= 9.389587847800895
# differential_evolution step 276: f(x)= 9.389587847800895
# differential_evolution step 277: f(x)= 9.389587847800895
# differential_evolution step 278: f(x)= 9.387378427163869
# differential_evolution step 279: f(x)= 9.387378427163869
# differential_evolution step 280: f(x)= 9.384173575471461
# differential_evolution step 281: f(x)= 9.384173575471461
# differential_evolution step 282: f(x)= 9.384173575471461
# differential_evolution step 283: f(x)= 9.384173575471461
# differential_evolution step 284: f(x)= 9.384173575471461
# differential_evolution step 285: f(x)= 9.384173575471461
# differential_evolution step 286: f(x)= 9.384173575471461
# differential_evolution step 287: f(x)= 9.384173575471461
# differential_evolution step 288: f(x)= 9.384173575471461
# differential_evolution step 289: f(x)= 9.384173575471461
# differential_evolution step 290: f(x)= 9.384173575471461
# differential_evolution step 291: f(x)= 9.380819313176717
# differential_evolution step 292: f(x)= 9.380819313176717
# differential_evolution step 293: f(x)= 9.380819313176717
# differential_evolution step 294: f(x)= 9.380819313176717
# differential_evolution step 295: f(x)= 9.380819313176717
# differential_evolution step 296: f(x)= 9.38052562887754
# differential_evolution step 297: f(x)= 9.379890285693948
# differential_evolution step 298: f(x)= 9.368662602210238
# differential_evolution step 299: f(x)= 9.362994617927434
# differential_evolution step 300: f(x)= 9.362994617927434
# differential_evolution step 301: f(x)= 9.362994617927434
# differential_evolution step 302: f(x)= 9.362994617927434
# differential_evolution step 303: f(x)= 9.362994617927434
# differential_evolution step 304: f(x)= 9.362994617927434
# differential_evolution step 305: f(x)= 9.362994617927434
# differential_evolution step 306: f(x)= 9.362994617927434
# differential_evolution step 307: f(x)= 9.360983098907015
# differential_evolution step 308: f(x)= 9.360983098907015
# differential_evolution step 309: f(x)= 9.358827360305334
# differential_evolution step 310: f(x)= 9.358827360305334
# differential_evolution step 311: f(x)= 9.353826814378865
# differential_evolution step 312: f(x)= 9.35251153480813
# differential_evolution step 313: f(x)= 9.350180898949938
# differential_evolution step 314: f(x)= 9.350180898949938
# differential_evolution step 315: f(x)= 9.350180898949938
# differential_evolution step 316: f(x)= 9.350180898949938
# differential_evolution step 317: f(x)= 9.350180898949938
# differential_evolution step 318: f(x)= 9.350180898949938
# differential_evolution step 319: f(x)= 9.350180898949938
# differential_evolution step 320: f(x)= 9.350180898949938
# differential_evolution step 321: f(x)= 9.346326453219177
# differential_evolution step 322: f(x)= 9.341409406532945
# differential_evolution step 323: f(x)= 9.329614103512428
# differential_evolution step 324: f(x)= 9.329614103512428
# differential_evolution step 325: f(x)= 9.329614103512428
# differential_evolution step 326: f(x)= 9.3212565172634
# differential_evolution step 327: f(x)= 9.31789723257686
# differential_evolution step 328: f(x)= 9.31765186041437
# differential_evolution step 329: f(x)= 9.310584308859202
# differential_evolution step 330: f(x)= 9.310584308859202
# differential_evolution step 331: f(x)= 9.310584308859202
# differential_evolution step 332: f(x)= 9.310584308859202
# differential_evolution step 333: f(x)= 9.310584308859202
# differential_evolution step 334: f(x)= 9.310584308859202
# differential_evolution step 335: f(x)= 9.310584308859202
# differential_evolution step 336: f(x)= 9.310584308859202
# differential_evolution step 337: f(x)= 9.310584308859202
# differential_evolution step 338: f(x)= 9.310584308859202
# differential_evolution step 339: f(x)= 9.309726728130405
# differential_evolution step 340: f(x)= 9.30966782035403
# differential_evolution step 341: f(x)= 9.30966782035403
# differential_evolution step 342: f(x)= 9.306441637466708
# differential_evolution step 343: f(x)= 9.306441637466708
# differential_evolution step 344: f(x)= 9.306441637466708
# differential_evolution step 345: f(x)= 9.306441637466708
# differential_evolution step 346: f(x)= 9.304617074813718
# differential_evolution step 347: f(x)= 9.304617074813718
# differential_evolution step 348: f(x)= 9.304617074813718
# differential_evolution step 349: f(x)= 9.304617074813718
# differential_evolution step 350: f(x)= 9.304617074813718
# differential_evolution step 351: f(x)= 9.304617074813718
# differential_evolution step 352: f(x)= 9.304617074813718
# differential_evolution step 353: f(x)= 9.304544683849164
# differential_evolution step 354: f(x)= 9.301456645834861
# differential_evolution step 355: f(x)= 9.301456645834861
# differential_evolution step 356: f(x)= 9.298493703001697
# differential_evolution step 357: f(x)= 9.297763718375135
# differential_evolution step 358: f(x)= 9.297763718375135
# differential_evolution step 359: f(x)= 9.297763718375135
# differential_evolution step 360: f(x)= 9.297763718375135
# differential_evolution step 361: f(x)= 9.297763718375135
# differential_evolution step 362: f(x)= 9.297763718375135
# differential_evolution step 363: f(x)= 9.297763718375135
# differential_evolution step 364: f(x)= 9.297763718375135
# differential_evolution step 365: f(x)= 9.295419998972898
# differential_evolution step 366: f(x)= 9.295419998972898
# differential_evolution step 367: f(x)= 9.294790942357624
# differential_evolution step 368: f(x)= 9.28754517999661
# differential_evolution step 369: f(x)= 9.276422445789123
# differential_evolution step 370: f(x)= 9.276422445789123
# differential_evolution step 371: f(x)= 9.276422445789123
# differential_evolution step 372: f(x)= 9.276422445789123
# differential_evolution step 373: f(x)= 9.276422445789123
# differential_evolution step 374: f(x)= 9.276422445789123
# differential_evolution step 375: f(x)= 9.276422445789123
# differential_evolution step 376: f(x)= 9.276422445789123
# differential_evolution step 377: f(x)= 9.275330298937474
# differential_evolution step 378: f(x)= 9.275330298937474
# differential_evolution step 379: f(x)= 9.275330298937474
# differential_evolution step 380: f(x)= 9.275330298937474
# differential_evolution step 381: f(x)= 9.275330298937474
# differential_evolution step 382: f(x)= 9.275330298937474
# differential_evolution step 383: f(x)= 9.275330298937474
# differential_evolution step 384: f(x)= 9.275330298937474
# differential_evolution step 385: f(x)= 9.275330298937474
# differential_evolution step 386: f(x)= 9.27487730268608
# differential_evolution step 387: f(x)= 9.27245399775396
# differential_evolution step 388: f(x)= 9.27245399775396
# differential_evolution step 389: f(x)= 9.27245399775396
# differential_evolution step 390: f(x)= 9.27245399775396
# differential_evolution step 391: f(x)= 9.27245399775396
# differential_evolution step 392: f(x)= 9.270261185623733
# differential_evolution step 393: f(x)= 9.270261185623733
# differential_evolution step 394: f(x)= 9.26835065213398
# differential_evolution step 395: f(x)= 9.26835065213398
# differential_evolution step 396: f(x)= 9.26835065213398
# differential_evolution step 397: f(x)= 9.26835065213398
# differential_evolution step 398: f(x)= 9.26835065213398
# differential_evolution step 399: f(x)= 9.26606802923409
# differential_evolution step 400: f(x)= 9.26606802923409
# differential_evolution step 401: f(x)= 9.26606802923409
# differential_evolution step 402: f(x)= 9.26606802923409
# differential_evolution step 403: f(x)= 9.26606802923409
# differential_evolution step 404: f(x)= 9.26606802923409
# differential_evolution step 405: f(x)= 9.26606802923409
# differential_evolution step 406: f(x)= 9.26606802923409
# differential_evolution step 407: f(x)= 9.263893779919677
# differential_evolution step 408: f(x)= 9.263893779919677
# differential_evolution step 409: f(x)= 9.263893779919677
# differential_evolution step 410: f(x)= 9.263893779919677
# differential_evolution step 411: f(x)= 9.263893779919677
# differential_evolution step 412: f(x)= 9.263893779919677
# differential_evolution step 413: f(x)= 9.263893779919677
# differential_evolution step 414: f(x)= 9.263893779919677
# differential_evolution step 415: f(x)= 9.263893779919677
# differential_evolution step 416: f(x)= 9.263893779919677
# differential_evolution step 417: f(x)= 9.263893779919677
# differential_evolution step 418: f(x)= 9.262283178191888
# differential_evolution step 419: f(x)= 9.262283178191888
# differential_evolution step 420: f(x)= 9.262283178191888
# differential_evolution step 421: f(x)= 9.262283178191888
# differential_evolution step 422: f(x)= 9.262283178191888
# differential_evolution step 423: f(x)= 9.262283178191888
# differential_evolution step 424: f(x)= 9.262283178191888
# differential_evolution step 425: f(x)= 9.262095857314918
# differential_evolution step 426: f(x)= 9.259641471924269
# differential_evolution step 427: f(x)= 9.259641471924269
# differential_evolution step 428: f(x)= 9.259641471924269
# differential_evolution step 429: f(x)= 9.259641471924269
# differential_evolution step 430: f(x)= 9.25839604775349
# differential_evolution step 431: f(x)= 9.25839604775349
# differential_evolution step 432: f(x)= 9.257282866889744
# differential_evolution step 433: f(x)= 9.256989900492382
# differential_evolution step 434: f(x)= 9.25622884917075
# differential_evolution step 435: f(x)= 9.25622884917075
# differential_evolution step 436: f(x)= 9.25622884917075
# differential_evolution step 437: f(x)= 9.25622884917075
# differential_evolution step 438: f(x)= 9.25622884917075
# differential_evolution step 439: f(x)= 9.25622884917075
# differential_evolution step 440: f(x)= 9.25622884917075
# differential_evolution step 441: f(x)= 9.25622884917075
# differential_evolution step 442: f(x)= 9.25622884917075
# differential_evolution step 443: f(x)= 9.25622884917075
# differential_evolution step 444: f(x)= 9.25622884917075
# differential_evolution step 445: f(x)= 9.25622884917075
# differential_evolution step 446: f(x)= 9.25622884917075
# differential_evolution step 447: f(x)= 9.25622884917075
# differential_evolution step 448: f(x)= 9.25622884917075
# differential_evolution step 449: f(x)= 9.25622884917075
# differential_evolution step 450: f(x)= 9.25622884917075
# differential_evolution step 451: f(x)= 9.25622884917075
# differential_evolution step 452: f(x)= 9.25622884917075
# differential_evolution step 453: f(x)= 9.25622884917075
# differential_evolution step 454: f(x)= 9.25622884917075
# differential_evolution step 455: f(x)= 9.25622884917075
# differential_evolution step 456: f(x)= 9.25622884917075
# differential_evolution step 457: f(x)= 9.25622884917075
# differential_evolution step 458: f(x)= 9.256144238764934
# differential_evolution step 459: f(x)= 9.256144238764934
# differential_evolution step 460: f(x)= 9.256144238764934
# differential_evolution step 461: f(x)= 9.256144238764934
# differential_evolution step 462: f(x)= 9.2555886857179
# differential_evolution step 463: f(x)= 9.2555886857179
# differential_evolution step 464: f(x)= 9.2555886857179
# differential_evolution step 465: f(x)= 9.2555886857179
# differential_evolution step 466: f(x)= 9.254589738669837
# differential_evolution step 467: f(x)= 9.254589738669837
# differential_evolution step 468: f(x)= 9.254589738669837
# differential_evolution step 469: f(x)= 9.254589738669837
# differential_evolution step 470: f(x)= 9.254589738669837
# differential_evolution step 471: f(x)= 9.254589738669837
# differential_evolution step 472: f(x)= 9.254589738669837
# differential_evolution step 473: f(x)= 9.254589738669837
# differential_evolution step 474: f(x)= 9.253655055233924
# differential_evolution step 475: f(x)= 9.253655055233924
# differential_evolution step 476: f(x)= 9.253655055233924
# differential_evolution step 477: f(x)= 9.253599626632854
# differential_evolution step 478: f(x)= 9.2535080015994
# differential_evolution step 479: f(x)= 9.2535080015994
# differential_evolution step 480: f(x)= 9.2535080015994
# differential_evolution step 481: f(x)= 9.2535080015994
# differential_evolution step 482: f(x)= 9.2535080015994
# differential_evolution step 483: f(x)= 9.2535080015994
# differential_evolution step 484: f(x)= 9.2535080015994
# differential_evolution step 485: f(x)= 9.2535080015994
# differential_evolution step 486: f(x)= 9.2535080015994
# differential_evolution step 487: f(x)= 9.252713700414953
# differential_evolution step 488: f(x)= 9.252713700414953
# differential_evolution step 489: f(x)= 9.252713700414953
# differential_evolution step 490: f(x)= 9.252713700414953
# differential_evolution step 491: f(x)= 9.252713700414953
# differential_evolution step 492: f(x)= 9.252713700414953
# differential_evolution step 493: f(x)= 9.252713700414953
# differential_evolution step 494: f(x)= 9.252713700414953
# differential_evolution step 495: f(x)= 9.252713700414953
# differential_evolution step 496: f(x)= 9.252713700414953
# differential_evolution step 497: f(x)= 9.252713700414953
# differential_evolution step 498: f(x)= 9.252713700414953
# differential_evolution step 499: f(x)= 9.252713700414953
# differential_evolution step 500: f(x)= 9.252713700414953
# differential_evolution step 501: f(x)= 9.252057800143143
# differential_evolution step 502: f(x)= 9.252057800143143
# differential_evolution step 503: f(x)= 9.252057800143143
# differential_evolution step 504: f(x)= 9.252057800143143
# differential_evolution step 505: f(x)= 9.252057800143143
# differential_evolution step 506: f(x)= 9.252057800143143
# differential_evolution step 507: f(x)= 9.252057800143143
# differential_evolution step 508: f(x)= 9.252057800143143
# differential_evolution step 509: f(x)= 9.252057800143143
# differential_evolution step 510: f(x)= 9.252057800143143
# differential_evolution step 511: f(x)= 9.252057800143143
# differential_evolution step 512: f(x)= 9.252057800143143
# differential_evolution step 513: f(x)= 9.252057800143143
# differential_evolution step 514: f(x)= 9.252057800143143
# differential_evolution step 515: f(x)= 9.252057800143143
# differential_evolution step 516: f(x)= 9.252057800143143
# differential_evolution step 517: f(x)= 9.252057800143143
# differential_evolution step 518: f(x)= 9.251975865659606
# differential_evolution step 519: f(x)= 9.251975865659606
# differential_evolution step 520: f(x)= 9.251893897058531
# differential_evolution step 521: f(x)= 9.251893897058531
# differential_evolution step 522: f(x)= 9.251893897058531
# differential_evolution step 523: f(x)= 9.251787577359934
# differential_evolution step 524: f(x)= 9.251787577359934
# differential_evolution step 525: f(x)= 9.251787577359934
# differential_evolution step 526: f(x)= 9.251787577359934
# differential_evolution step 527: f(x)= 9.25154437337807
# differential_evolution step 528: f(x)= 9.25154437337807
# differential_evolution step 529: f(x)= 9.25154437337807
# differential_evolution step 530: f(x)= 9.25154437337807
# differential_evolution step 531: f(x)= 9.25154437337807
# differential_evolution step 532: f(x)= 9.25154437337807
# differential_evolution step 533: f(x)= 9.25154437337807
# differential_evolution step 534: f(x)= 9.251505590536436
# differential_evolution step 535: f(x)= 9.251408647215301
# differential_evolution step 536: f(x)= 9.251408647215301
# differential_evolution step 537: f(x)= 9.251408647215301
# differential_evolution step 538: f(x)= 9.251220118673558
# differential_evolution step 539: f(x)= 9.251220118673558
# differential_evolution step 540: f(x)= 9.251220118673558
# differential_evolution step 541: f(x)= 9.251092455624283
# differential_evolution step 542: f(x)= 9.251092455624283
# differential_evolution step 543: f(x)= 9.251092455624283
# differential_evolution step 544: f(x)= 9.250885159162527
# differential_evolution step 545: f(x)= 9.250885159162527
# differential_evolution step 546: f(x)= 9.250885159162527
# differential_evolution step 547: f(x)= 9.250885159162527
# differential_evolution step 548: f(x)= 9.250885159162527
# differential_evolution step 549: f(x)= 9.250885159162527
# differential_evolution step 550: f(x)= 9.250832146140086
# differential_evolution step 551: f(x)= 9.250832146140086
# differential_evolution step 552: f(x)= 9.250832146140086
# differential_evolution step 553: f(x)= 9.250832146140086
# differential_evolution step 554: f(x)= 9.250832146140086
# differential_evolution step 555: f(x)= 9.250832146140086
# differential_evolution step 556: f(x)= 9.250832146140086
# differential_evolution step 557: f(x)= 9.250832146140086
# differential_evolution step 558: f(x)= 9.250678541627387
# differential_evolution step 559: f(x)= 9.250678541627387
# differential_evolution step 560: f(x)= 9.250678541627387
# differential_evolution step 561: f(x)= 9.250678541627387
# differential_evolution step 562: f(x)= 9.250678541627387
# differential_evolution step 563: f(x)= 9.250678541627387
# differential_evolution step 564: f(x)= 9.250678541627387
# differential_evolution step 565: f(x)= 9.250678541627387
# differential_evolution step 566: f(x)= 9.250678541627387
# differential_evolution step 567: f(x)= 9.250678541627387
# differential_evolution step 568: f(x)= 9.250678541627387
# differential_evolution step 569: f(x)= 9.250678541627387
# differential_evolution step 570: f(x)= 9.25064870239897
# differential_evolution step 571: f(x)= 9.250563405213729
# differential_evolution step 572: f(x)= 9.250563405213729
# differential_evolution step 573: f(x)= 9.250563405213729
# differential_evolution step 574: f(x)= 9.250563405213729
# differential_evolution step 575: f(x)= 9.25050286231029
# differential_evolution step 576: f(x)= 9.25050286231029
# differential_evolution step 577: f(x)= 9.25050286231029
# differential_evolution step 578: f(x)= 9.25050286231029
# differential_evolution step 579: f(x)= 9.25050286231029
# differential_evolution step 580: f(x)= 9.25050286231029
# differential_evolution step 581: f(x)= 9.25050286231029
# differential_evolution step 582: f(x)= 9.25050286231029
# differential_evolution step 583: f(x)= 9.25050286231029
# differential_evolution step 584: f(x)= 9.25050286231029
# differential_evolution step 585: f(x)= 9.25050286231029
# differential_evolution step 586: f(x)= 9.25050286231029
# differential_evolution step 587: f(x)= 9.25040099496402
# differential_evolution step 588: f(x)= 9.25040099496402
# differential_evolution step 589: f(x)= 9.25040099496402
# differential_evolution step 590: f(x)= 9.25040099496402
# differential_evolution step 591: f(x)= 9.250325508685133
# differential_evolution step 592: f(x)= 9.250325508685133
# differential_evolution step 593: f(x)= 9.250325508685133
# differential_evolution step 594: f(x)= 9.250325508685133
# differential_evolution step 595: f(x)= 9.250325508685133
# differential_evolution step 596: f(x)= 9.250325508685133
# differential_evolution step 597: f(x)= 9.250325508685133
# differential_evolution step 598: f(x)= 9.250325508685133
# differential_evolution step 599: f(x)= 9.250325508685133
# differential_evolution step 600: f(x)= 9.250258776417613
# differential_evolution step 601: f(x)= 9.250243008013507
# differential_evolution step 602: f(x)= 9.250243008013507
# differential_evolution step 603: f(x)= 9.250243008013507
# differential_evolution step 604: f(x)= 9.250220602043663
# differential_evolution step 605: f(x)= 9.250220602043663
# differential_evolution step 606: f(x)= 9.250220602043663
# differential_evolution step 607: f(x)= 9.250220602043663
# differential_evolution step 608: f(x)= 9.250220602043663
# differential_evolution step 609: f(x)= 9.250220602043663
# differential_evolution step 610: f(x)= 9.250220602043663
# differential_evolution step 611: f(x)= 9.250220602043663
# differential_evolution step 612: f(x)= 9.250220602043663
# differential_evolution step 613: f(x)= 9.250220602043663
# differential_evolution step 614: f(x)= 9.250220602043663
# differential_evolution step 615: f(x)= 9.250220602043663
# differential_evolution step 616: f(x)= 9.250220602043663
# differential_evolution step 617: f(x)= 9.250190102687636
# differential_evolution step 618: f(x)= 9.250190102687636
# differential_evolution step 619: f(x)= 9.250190102687636
# differential_evolution step 620: f(x)= 9.250190102687636
# differential_evolution step 621: f(x)= 9.25017511282256
# differential_evolution step 622: f(x)= 9.25012545212248
# differential_evolution step 623: f(x)= 9.25012545212248
# differential_evolution step 624: f(x)= 9.25012545212248
# differential_evolution step 625: f(x)= 9.25012545212248
# differential_evolution step 626: f(x)= 9.25012545212248
# differential_evolution step 627: f(x)= 9.25012545212248
# differential_evolution step 628: f(x)= 9.25012545212248
# differential_evolution step 629: f(x)= 9.25012545212248
# differential_evolution step 630: f(x)= 9.25012545212248
# differential_evolution step 631: f(x)= 9.250124185101393
# differential_evolution step 632: f(x)= 9.250124185101393
# differential_evolution step 633: f(x)= 9.250124185101393
# differential_evolution step 634: f(x)= 9.250124185101393
# differential_evolution step 635: f(x)= 9.250124185101393
# differential_evolution step 636: f(x)= 9.250124185101393
# differential_evolution step 637: f(x)= 9.250124185101393
# differential_evolution step 638: f(x)= 9.250124185101393
# differential_evolution step 639: f(x)= 9.250114628575062
# differential_evolution step 640: f(x)= 9.250114628575062
# differential_evolution step 641: f(x)= 9.250113706102363
# differential_evolution step 642: f(x)= 9.250113706102363
# differential_evolution step 643: f(x)= 9.250113706102363
# differential_evolution step 644: f(x)= 9.250113706102363
# differential_evolution step 645: f(x)= 9.250113706102363
# differential_evolution step 646: f(x)= 9.250113706102363
# differential_evolution step 647: f(x)= 9.250113706102363
# differential_evolution step 648: f(x)= 9.250094239141923
# differential_evolution step 649: f(x)= 9.250094239141923
# differential_evolution step 650: f(x)= 9.250094239141923
# differential_evolution step 651: f(x)= 9.250094239141923
# differential_evolution step 652: f(x)= 9.250094239141923
# differential_evolution step 653: f(x)= 9.250094239141923
# differential_evolution step 654: f(x)= 9.250091723493988
# differential_evolution step 655: f(x)= 9.250091723493988
# differential_evolution step 656: f(x)= 9.250091723493988
# differential_evolution step 657: f(x)= 9.250077874089284
# differential_evolution step 658: f(x)= 9.250077874089284
# differential_evolution step 659: f(x)= 9.250077874089284
# differential_evolution step 660: f(x)= 9.250077874089284
# differential_evolution step 661: f(x)= 9.250070975233731
# differential_evolution step 662: f(x)= 9.250070975233731
# differential_evolution step 663: f(x)= 9.250070975233731
# differential_evolution step 664: f(x)= 9.25005872477221
# differential_evolution step 665: f(x)= 9.25005872477221
# differential_evolution step 666: f(x)= 9.25005872477221
# differential_evolution step 667: f(x)= 9.25005872477221
# differential_evolution step 668: f(x)= 9.25005872477221
# differential_evolution step 669: f(x)= 9.25005872477221
# differential_evolution step 670: f(x)= 9.25005872477221
# differential_evolution step 671: f(x)= 9.25005872477221
# differential_evolution step 672: f(x)= 9.25005872477221
# differential_evolution step 673: f(x)= 9.25005872477221
# differential_evolution step 674: f(x)= 9.250052995182815
# differential_evolution step 675: f(x)= 9.250052995182815
# differential_evolution step 676: f(x)= 9.250052995182815
# differential_evolution step 677: f(x)= 9.250050923671527
# differential_evolution step 678: f(x)= 9.250050923671527
# differential_evolution step 679: f(x)= 9.250050923671527
# differential_evolution step 680: f(x)= 9.250050923671527
# differential_evolution step 681: f(x)= 9.250050923671527
# differential_evolution step 682: f(x)= 9.250050923671527
# differential_evolution step 683: f(x)= 9.250050923671527
# differential_evolution step 684: f(x)= 9.250050923671527
# differential_evolution step 685: f(x)= 9.250050923671527
# differential_evolution step 686: f(x)= 9.250050923671527
# differential_evolution step 687: f(x)= 9.250050923671527
# differential_evolution step 688: f(x)= 9.250050923671527
# differential_evolution step 689: f(x)= 9.25004952118293
# differential_evolution step 690: f(x)= 9.25004952118293
# differential_evolution step 691: f(x)= 9.25004952118293
# differential_evolution step 692: f(x)= 9.25004952118293
# differential_evolution step 693: f(x)= 9.250046953054628
# differential_evolution step 694: f(x)= 9.250046953054628
# differential_evolution step 695: f(x)= 9.250046953054628
# differential_evolution step 696: f(x)= 9.250046953054628
# differential_evolution step 697: f(x)= 9.250044466267319
# differential_evolution step 698: f(x)= 9.250041997874828
# differential_evolution step 699: f(x)= 9.250041997874828
# differential_evolution step 700: f(x)= 9.250041997874828
# differential_evolution step 701: f(x)= 9.250036460251692
# differential_evolution step 702: f(x)= 9.250036460251692
# differential_evolution step 703: f(x)= 9.250036460251692
# differential_evolution step 704: f(x)= 9.250036460251692
# differential_evolution step 705: f(x)= 9.250036460251692
# differential_evolution step 706: f(x)= 9.250036460251692
# differential_evolution step 707: f(x)= 9.250036460251692
# differential_evolution step 708: f(x)= 9.250036460251692
# differential_evolution step 709: f(x)= 9.250030163839714
# differential_evolution step 710: f(x)= 9.250030163839714
# differential_evolution step 711: f(x)= 9.250030163839714
# differential_evolution step 712: f(x)= 9.250030163839714
# differential_evolution step 713: f(x)= 9.250030163839714
# differential_evolution step 714: f(x)= 9.250030163839714
# differential_evolution step 715: f(x)= 9.250030163839714
# differential_evolution step 716: f(x)= 9.250029542348859
# differential_evolution step 717: f(x)= 9.25002248036414
# differential_evolution step 718: f(x)= 9.25002248036414
# differential_evolution step 719: f(x)= 9.25002248036414
# differential_evolution step 720: f(x)= 9.25002248036414
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1915, r_e=49.9999, n=2.5610, x_0=38.4561
# Sérsic 2: I_e=0.0155, r_e=49.9996, n=4.1277, x_0=48.5597
# Sérsic 3: I_e=0.0470, r_e=49.9983, n=2.5737, x_0=80.8290
# Chi quadro minimo: 9.25002248036414
# True

# %%
plot_diff(x_axes, best_params, radial_profile_SII, r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')

# %%
params_curve_SII, covariance_SII = curve_fit(model_convolved, x_axes, radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII)

chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, radial_profile_error_SII,
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_19040\2374069783.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_19040\2374069783.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Sérsic 1: I_e=0.1806, r_e=48.2428, n=2.6036, x_0=38.2901
# Sérsic 2: I_e=0.0152, r_e=83.9809, n=3.8257, x_0=48.5964
# Sérsic 3: I_e=0.0466, r_e=44.9196, n=2.6155, x_0=80.8281
# [1.47407764e-01 3.99787572e+01 5.38002479e-01 9.57113392e-02
#  2.08185057e-01 9.32248817e+02 1.09168891e+01 5.26471468e-04
#  1.01497377e-01 8.86926877e+01 1.52760122e+00 2.03767589e-01]
# 66.57459767711647

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 329.03232531550736
# differential_evolution step 2: f(x)= 255.75862538277636
# differential_evolution step 3: f(x)= 161.90285532692022
# differential_evolution step 4: f(x)= 155.77546459235606
# differential_evolution step 5: f(x)= 141.70309857180555
# differential_evolution step 6: f(x)= 104.84912451761686
# differential_evolution step 7: f(x)= 104.84912451761686
# differential_evolution step 8: f(x)= 104.84912451761686
# differential_evolution step 9: f(x)= 104.84912451761686
# differential_evolution step 10: f(x)= 104.84912451761686
# differential_evolution step 11: f(x)= 104.84912451761686
# differential_evolution step 12: f(x)= 104.84912451761686
# differential_evolution step 13: f(x)= 104.84912451761686
# differential_evolution step 14: f(x)= 78.00636509883418
# differential_evolution step 15: f(x)= 73.62104135553186
# differential_evolution step 16: f(x)= 73.62104135553186
# differential_evolution step 17: f(x)= 73.62104135553186
# differential_evolution step 18: f(x)= 57.80021475099757
# differential_evolution step 19: f(x)= 57.80021475099757
# differential_evolution step 20: f(x)= 57.80021475099757
# differential_evolution step 21: f(x)= 57.80021475099757
# differential_evolution step 22: f(x)= 57.80021475099757
# differential_evolution step 23: f(x)= 57.80021475099757
# differential_evolution step 24: f(x)= 57.80021475099757
# differential_evolution step 25: f(x)= 57.80021475099757
# differential_evolution step 26: f(x)= 56.36930138150156
# differential_evolution step 27: f(x)= 51.65733000521265
# differential_evolution step 28: f(x)= 51.65733000521265
# differential_evolution step 29: f(x)= 51.65733000521265
# differential_evolution step 30: f(x)= 51.65733000521265
# differential_evolution step 31: f(x)= 51.65733000521265
# differential_evolution step 32: f(x)= 51.65733000521265
# differential_evolution step 33: f(x)= 51.65733000521265
# differential_evolution step 34: f(x)= 51.65733000521265
# differential_evolution step 35: f(x)= 51.65733000521265
# differential_evolution step 36: f(x)= 51.65733000521265
# differential_evolution step 37: f(x)= 51.34645663660138
# differential_evolution step 38: f(x)= 47.38822818869615
# differential_evolution step 39: f(x)= 47.38822818869615
# differential_evolution step 40: f(x)= 47.38822818869615
# differential_evolution step 41: f(x)= 47.38822818869615
# differential_evolution step 42: f(x)= 44.98068051609857
# differential_evolution step 43: f(x)= 44.98068051609857
# differential_evolution step 44: f(x)= 44.98068051609857
# differential_evolution step 45: f(x)= 44.70123589252006
# differential_evolution step 46: f(x)= 44.70123589252006
# differential_evolution step 47: f(x)= 44.70123589252006
# differential_evolution step 48: f(x)= 44.70123589252006
# differential_evolution step 49: f(x)= 44.70123589252006
# differential_evolution step 50: f(x)= 44.70123589252006
# differential_evolution step 51: f(x)= 44.70123589252006
# differential_evolution step 52: f(x)= 44.70123589252006
# differential_evolution step 53: f(x)= 42.11758285559435
# differential_evolution step 54: f(x)= 42.11758285559435
# differential_evolution step 55: f(x)= 42.11758285559435
# differential_evolution step 56: f(x)= 42.11758285559435
# differential_evolution step 57: f(x)= 42.11758285559435
# differential_evolution step 58: f(x)= 42.11758285559435
# differential_evolution step 59: f(x)= 42.11758285559435
# differential_evolution step 60: f(x)= 42.11758285559435
# differential_evolution step 61: f(x)= 42.11758285559435
# differential_evolution step 62: f(x)= 42.11758285559435
# differential_evolution step 63: f(x)= 42.11758285559435
# differential_evolution step 64: f(x)= 42.11758285559435
# differential_evolution step 65: f(x)= 42.11758285559435
# differential_evolution step 66: f(x)= 42.11758285559435
# differential_evolution step 67: f(x)= 42.11758285559435
# differential_evolution step 68: f(x)= 42.11758285559435
# differential_evolution step 69: f(x)= 42.11758285559435
# differential_evolution step 70: f(x)= 42.11758285559435
# differential_evolution step 71: f(x)= 42.11758285559435
# differential_evolution step 72: f(x)= 42.11758285559435
# differential_evolution step 73: f(x)= 42.11758285559435
# differential_evolution step 74: f(x)= 42.11758285559435
# differential_evolution step 75: f(x)= 41.40199613125061
# differential_evolution step 76: f(x)= 41.40199613125061
# differential_evolution step 77: f(x)= 41.40199613125061
# differential_evolution step 78: f(x)= 41.40199613125061
# differential_evolution step 79: f(x)= 41.38971028968985
# differential_evolution step 80: f(x)= 41.02264375632996
# differential_evolution step 81: f(x)= 41.02264375632996
# differential_evolution step 82: f(x)= 41.02264375632996
# differential_evolution step 83: f(x)= 41.02264375632996
# differential_evolution step 84: f(x)= 41.02264375632996
# differential_evolution step 85: f(x)= 41.02264375632996
# differential_evolution step 86: f(x)= 41.01664517011967
# differential_evolution step 87: f(x)= 40.228200286110855
# differential_evolution step 88: f(x)= 40.228200286110855
# differential_evolution step 89: f(x)= 40.228200286110855
# differential_evolution step 90: f(x)= 40.228200286110855
# differential_evolution step 91: f(x)= 40.228200286110855
# differential_evolution step 92: f(x)= 40.228200286110855
# differential_evolution step 93: f(x)= 40.228200286110855
# differential_evolution step 94: f(x)= 40.228200286110855
# differential_evolution step 95: f(x)= 40.228200286110855
# differential_evolution step 96: f(x)= 40.228200286110855
# differential_evolution step 97: f(x)= 40.228200286110855
# differential_evolution step 98: f(x)= 40.228200286110855
# differential_evolution step 99: f(x)= 40.228200286110855
# differential_evolution step 100: f(x)= 40.228200286110855
# differential_evolution step 101: f(x)= 40.228200286110855
# differential_evolution step 102: f(x)= 40.228200286110855
# differential_evolution step 103: f(x)= 40.228200286110855
# differential_evolution step 104: f(x)= 40.228200286110855
# differential_evolution step 105: f(x)= 40.228200286110855
# differential_evolution step 106: f(x)= 40.228200286110855
# differential_evolution step 107: f(x)= 40.228200286110855
# differential_evolution step 108: f(x)= 40.228200286110855
# differential_evolution step 109: f(x)= 40.228200286110855
# differential_evolution step 110: f(x)= 40.228200286110855
# differential_evolution step 111: f(x)= 39.67096247813099
# differential_evolution step 112: f(x)= 39.67096247813099
# differential_evolution step 113: f(x)= 39.67096247813099
# differential_evolution step 114: f(x)= 39.67096247813099
# differential_evolution step 115: f(x)= 39.67096247813099
# differential_evolution step 116: f(x)= 39.67096247813099
# differential_evolution step 117: f(x)= 39.67096247813099
# differential_evolution step 118: f(x)= 39.67096247813099
# differential_evolution step 119: f(x)= 39.67096247813099
# differential_evolution step 120: f(x)= 39.67096247813099
# differential_evolution step 121: f(x)= 39.67096247813099
# differential_evolution step 122: f(x)= 39.639521529951146
# differential_evolution step 123: f(x)= 39.639521529951146
# differential_evolution step 124: f(x)= 39.639521529951146
# differential_evolution step 125: f(x)= 39.639521529951146
# differential_evolution step 126: f(x)= 39.639521529951146
# differential_evolution step 127: f(x)= 39.639521529951146
# differential_evolution step 128: f(x)= 39.639521529951146
# differential_evolution step 129: f(x)= 39.639521529951146
# differential_evolution step 130: f(x)= 39.639521529951146
# differential_evolution step 131: f(x)= 39.639521529951146
# differential_evolution step 132: f(x)= 39.639521529951146
# differential_evolution step 133: f(x)= 39.639521529951146
# differential_evolution step 134: f(x)= 39.639521529951146
# differential_evolution step 135: f(x)= 39.639521529951146
# differential_evolution step 136: f(x)= 39.639521529951146
# differential_evolution step 137: f(x)= 39.639521529951146
# differential_evolution step 138: f(x)= 39.625461216947436
# differential_evolution step 139: f(x)= 39.625461216947436
# differential_evolution step 140: f(x)= 39.625461216947436
# differential_evolution step 141: f(x)= 39.625461216947436
# differential_evolution step 142: f(x)= 39.51019102186237
# differential_evolution step 143: f(x)= 39.51019102186237
# differential_evolution step 144: f(x)= 39.51019102186237
# differential_evolution step 145: f(x)= 39.3102605497741
# differential_evolution step 146: f(x)= 39.3102605497741
# differential_evolution step 147: f(x)= 39.3102605497741
# differential_evolution step 148: f(x)= 39.3102605497741
# differential_evolution step 149: f(x)= 39.3102605497741
# differential_evolution step 150: f(x)= 39.3102605497741
# differential_evolution step 151: f(x)= 39.3102605497741
# differential_evolution step 152: f(x)= 39.3102605497741
# differential_evolution step 153: f(x)= 39.3102605497741
# differential_evolution step 154: f(x)= 39.3102605497741
# differential_evolution step 155: f(x)= 39.3102605497741
# differential_evolution step 156: f(x)= 39.21430746936108
# differential_evolution step 157: f(x)= 39.21430746936108
# differential_evolution step 158: f(x)= 39.21430746936108
# differential_evolution step 159: f(x)= 39.21430746936108
# differential_evolution step 160: f(x)= 39.21430746936108
# differential_evolution step 161: f(x)= 39.21430746936108
# differential_evolution step 162: f(x)= 39.21430746936108
# differential_evolution step 163: f(x)= 39.21430746936108
# differential_evolution step 164: f(x)= 39.21430746936108
# differential_evolution step 165: f(x)= 39.21430746936108
# differential_evolution step 166: f(x)= 39.21430746936108
# differential_evolution step 167: f(x)= 39.21430746936108
# differential_evolution step 168: f(x)= 39.048206645638594
# differential_evolution step 169: f(x)= 39.048206645638594
# differential_evolution step 170: f(x)= 39.048206645638594
# differential_evolution step 171: f(x)= 39.048206645638594
# differential_evolution step 172: f(x)= 39.048206645638594
# differential_evolution step 173: f(x)= 39.048206645638594
# differential_evolution step 174: f(x)= 39.048206645638594
# differential_evolution step 175: f(x)= 39.048206645638594
# differential_evolution step 176: f(x)= 39.048206645638594
# differential_evolution step 177: f(x)= 39.048206645638594
# differential_evolution step 178: f(x)= 39.048206645638594
# differential_evolution step 179: f(x)= 39.048206645638594
# differential_evolution step 180: f(x)= 39.01626374722594
# differential_evolution step 181: f(x)= 38.885621175433165
# differential_evolution step 182: f(x)= 38.885621175433165
# differential_evolution step 183: f(x)= 38.885621175433165
# differential_evolution step 184: f(x)= 38.81231102283262
# differential_evolution step 185: f(x)= 38.81231102283262
# differential_evolution step 186: f(x)= 38.80531375637342
# differential_evolution step 187: f(x)= 38.80531375637342
# differential_evolution step 188: f(x)= 38.80531375637342
# differential_evolution step 189: f(x)= 38.80531375637342
# differential_evolution step 190: f(x)= 38.80531375637342
# differential_evolution step 191: f(x)= 38.80531375637342
# differential_evolution step 192: f(x)= 38.80531375637342
# differential_evolution step 193: f(x)= 38.80531375637342
# differential_evolution step 194: f(x)= 38.80531375637342
# differential_evolution step 195: f(x)= 38.74835090798072
# differential_evolution step 196: f(x)= 38.66970821279273
# differential_evolution step 197: f(x)= 38.66970821279273
# differential_evolution step 198: f(x)= 38.66970821279273
# differential_evolution step 199: f(x)= 38.66970821279273
# differential_evolution step 200: f(x)= 38.66970821279273
# differential_evolution step 201: f(x)= 38.66970821279273
# differential_evolution step 202: f(x)= 38.66970821279273
# differential_evolution step 203: f(x)= 38.66970821279273
# differential_evolution step 204: f(x)= 38.563293656309526
# differential_evolution step 205: f(x)= 38.524218344114175
# differential_evolution step 206: f(x)= 38.524218344114175
# differential_evolution step 207: f(x)= 38.524218344114175
# differential_evolution step 208: f(x)= 38.524218344114175
# differential_evolution step 209: f(x)= 38.39156386959635
# differential_evolution step 210: f(x)= 38.39156386959635
# differential_evolution step 211: f(x)= 38.39156386959635
# differential_evolution step 212: f(x)= 38.39156386959635
# differential_evolution step 213: f(x)= 38.39156386959635
# differential_evolution step 214: f(x)= 38.39156386959635
# differential_evolution step 215: f(x)= 38.39156386959635
# differential_evolution step 216: f(x)= 38.39156386959635
# differential_evolution step 217: f(x)= 38.39156386959635
# differential_evolution step 218: f(x)= 38.39156386959635
# differential_evolution step 219: f(x)= 38.39156386959635
# differential_evolution step 220: f(x)= 38.39156386959635
# differential_evolution step 221: f(x)= 38.39156386959635
# differential_evolution step 222: f(x)= 38.39156386959635
# differential_evolution step 223: f(x)= 38.25691563559507
# differential_evolution step 224: f(x)= 38.25691563559507
# differential_evolution step 225: f(x)= 38.25691563559507
# differential_evolution step 226: f(x)= 38.25691563559507
# differential_evolution step 227: f(x)= 38.25691563559507
# differential_evolution step 228: f(x)= 38.25691563559507
# differential_evolution step 229: f(x)= 38.25691563559507
# differential_evolution step 230: f(x)= 38.25691563559507
# differential_evolution step 231: f(x)= 38.25691563559507
# differential_evolution step 232: f(x)= 38.25691563559507
# differential_evolution step 233: f(x)= 38.25691563559507
# differential_evolution step 234: f(x)= 38.25691563559507
# differential_evolution step 235: f(x)= 38.25691563559507
# differential_evolution step 236: f(x)= 38.25691563559507
# differential_evolution step 237: f(x)= 38.22715300526114
# differential_evolution step 238: f(x)= 38.22715300526114
# differential_evolution step 239: f(x)= 38.22715300526114
# differential_evolution step 240: f(x)= 38.22715300526114
# differential_evolution step 241: f(x)= 38.22715300526114
# differential_evolution step 242: f(x)= 38.15022288438048
# differential_evolution step 243: f(x)= 38.15022288438048
# differential_evolution step 244: f(x)= 38.15022288438048
# differential_evolution step 245: f(x)= 38.15022288438048
# differential_evolution step 246: f(x)= 38.15022288438048
# differential_evolution step 247: f(x)= 38.15022288438048
# differential_evolution step 248: f(x)= 38.15022288438048
# differential_evolution step 249: f(x)= 38.15022288438048
# differential_evolution step 250: f(x)= 38.15022288438048
# differential_evolution step 251: f(x)= 38.14379348764381
# differential_evolution step 252: f(x)= 38.14379348764381
# differential_evolution step 253: f(x)= 38.14379348764381
# differential_evolution step 254: f(x)= 38.14379348764381
# differential_evolution step 255: f(x)= 38.14379348764381
# differential_evolution step 256: f(x)= 38.14379348764381
# differential_evolution step 257: f(x)= 38.14379348764381
# differential_evolution step 258: f(x)= 38.14379348764381
# differential_evolution step 259: f(x)= 38.14379348764381
# differential_evolution step 260: f(x)= 38.14379348764381
# differential_evolution step 261: f(x)= 38.14379348764381
# differential_evolution step 262: f(x)= 38.14379348764381
# differential_evolution step 263: f(x)= 38.14379348764381
# differential_evolution step 264: f(x)= 38.14379348764381
# differential_evolution step 265: f(x)= 38.14379348764381
# differential_evolution step 266: f(x)= 38.14379348764381
# differential_evolution step 267: f(x)= 38.14379348764381
# differential_evolution step 268: f(x)= 38.14379348764381
# differential_evolution step 269: f(x)= 38.14379348764381
# differential_evolution step 270: f(x)= 38.04714587437339
# differential_evolution step 271: f(x)= 38.04714587437339
# differential_evolution step 272: f(x)= 38.04714587437339
# differential_evolution step 273: f(x)= 38.04714587437339
# differential_evolution step 274: f(x)= 38.04714587437339
# differential_evolution step 275: f(x)= 38.04714587437339
# differential_evolution step 276: f(x)= 38.04714587437339
# differential_evolution step 277: f(x)= 38.04714587437339
# differential_evolution step 278: f(x)= 38.04714587437339
# differential_evolution step 279: f(x)= 38.04714587437339
# differential_evolution step 280: f(x)= 38.04714587437339
# differential_evolution step 281: f(x)= 38.04714587437339
# differential_evolution step 282: f(x)= 38.04714587437339
# differential_evolution step 283: f(x)= 38.04714587437339
# differential_evolution step 284: f(x)= 38.04714587437339
# differential_evolution step 285: f(x)= 38.04714587437339
# differential_evolution step 286: f(x)= 38.04714587437339
# differential_evolution step 287: f(x)= 38.04714587437339
# differential_evolution step 288: f(x)= 38.04714587437339
# differential_evolution step 289: f(x)= 38.02554322969492
# differential_evolution step 290: f(x)= 37.9990547093443
# differential_evolution step 291: f(x)= 37.9990547093443
# differential_evolution step 292: f(x)= 37.9990547093443
# differential_evolution step 293: f(x)= 37.9990547093443
# differential_evolution step 294: f(x)= 37.962716452248124
# differential_evolution step 295: f(x)= 37.92598935004317
# differential_evolution step 296: f(x)= 37.92598935004317
# differential_evolution step 297: f(x)= 37.91006471707203
# differential_evolution step 298: f(x)= 37.91006471707203
# differential_evolution step 299: f(x)= 37.91006471707203
# differential_evolution step 300: f(x)= 37.91006471707203
# differential_evolution step 301: f(x)= 37.90939368902874
# differential_evolution step 302: f(x)= 37.90939368902874
# differential_evolution step 303: f(x)= 37.85719133999771
# differential_evolution step 304: f(x)= 37.85719133999771
# differential_evolution step 305: f(x)= 37.85719133999771
# differential_evolution step 306: f(x)= 37.85719133999771
# differential_evolution step 307: f(x)= 37.85719133999771
# differential_evolution step 308: f(x)= 37.85719133999771
# differential_evolution step 309: f(x)= 37.85719133999771
# differential_evolution step 310: f(x)= 37.85719133999771
# differential_evolution step 311: f(x)= 37.85719133999771
# differential_evolution step 312: f(x)= 37.85719133999771
# differential_evolution step 313: f(x)= 37.85719133999771
# differential_evolution step 314: f(x)= 37.85719133999771
# differential_evolution step 315: f(x)= 37.85719133999771
# differential_evolution step 316: f(x)= 37.85719133999771
# differential_evolution step 317: f(x)= 37.85719133999771
# differential_evolution step 318: f(x)= 37.85719133999771
# differential_evolution step 319: f(x)= 37.85719133999771
# differential_evolution step 320: f(x)= 37.85719133999771
# differential_evolution step 321: f(x)= 37.85719133999771
# differential_evolution step 322: f(x)= 37.85719133999771
# differential_evolution step 323: f(x)= 37.85719133999771
# differential_evolution step 324: f(x)= 37.85719133999771
# differential_evolution step 325: f(x)= 37.85719133999771
# differential_evolution step 326: f(x)= 37.85719133999771
# differential_evolution step 327: f(x)= 37.85719133999771
# differential_evolution step 328: f(x)= 37.85719133999771
# differential_evolution step 329: f(x)= 37.85719133999771
# differential_evolution step 330: f(x)= 37.85719133999771
# differential_evolution step 331: f(x)= 37.85719133999771
# differential_evolution step 332: f(x)= 37.85719133999771
# differential_evolution step 333: f(x)= 37.85719133999771
# differential_evolution step 334: f(x)= 37.85719133999771
# differential_evolution step 335: f(x)= 37.85719133999771
# differential_evolution step 336: f(x)= 37.85719133999771
# differential_evolution step 337: f(x)= 37.85719133999771
# differential_evolution step 338: f(x)= 37.85719133999771
# differential_evolution step 339: f(x)= 37.83106578149505
# differential_evolution step 340: f(x)= 37.83106578149505
# differential_evolution step 341: f(x)= 37.83106578149505
# differential_evolution step 342: f(x)= 37.83106578149505
# differential_evolution step 343: f(x)= 37.83106578149505
# differential_evolution step 344: f(x)= 37.83106578149505
# differential_evolution step 345: f(x)= 37.83106578149505
# differential_evolution step 346: f(x)= 37.792835282774014
# differential_evolution step 347: f(x)= 37.792835282774014
# differential_evolution step 348: f(x)= 37.792835282774014
# differential_evolution step 349: f(x)= 37.792835282774014
# differential_evolution step 350: f(x)= 37.792835282774014
# differential_evolution step 351: f(x)= 37.79211855306026
# differential_evolution step 352: f(x)= 37.79211855306026
# differential_evolution step 353: f(x)= 37.79211855306026
# differential_evolution step 354: f(x)= 37.79211855306026
# differential_evolution step 355: f(x)= 37.79211855306026
# differential_evolution step 356: f(x)= 37.79211855306026
# differential_evolution step 357: f(x)= 37.79211855306026
# differential_evolution step 358: f(x)= 37.79211855306026
# differential_evolution step 359: f(x)= 37.79211855306026
# differential_evolution step 360: f(x)= 37.79211855306026
# differential_evolution step 361: f(x)= 37.79211855306026
# differential_evolution step 362: f(x)= 37.77741944699886
# differential_evolution step 363: f(x)= 37.76933476144429
# differential_evolution step 364: f(x)= 37.76933476144429
# differential_evolution step 365: f(x)= 37.76933476144429
# differential_evolution step 366: f(x)= 37.76933476144429
# differential_evolution step 367: f(x)= 37.76933476144429
# differential_evolution step 368: f(x)= 37.76933476144429
# differential_evolution step 369: f(x)= 37.76933476144429
# differential_evolution step 370: f(x)= 37.76933476144429
# differential_evolution step 371: f(x)= 37.73382052919296
# differential_evolution step 372: f(x)= 37.73382052919296
# differential_evolution step 373: f(x)= 37.73382052919296
# differential_evolution step 374: f(x)= 37.73382052919296
# differential_evolution step 375: f(x)= 37.73382052919296
# differential_evolution step 376: f(x)= 37.73382052919296
# differential_evolution step 377: f(x)= 37.73382052919296
# differential_evolution step 378: f(x)= 37.73382052919296
# differential_evolution step 379: f(x)= 37.73382052919296
# differential_evolution step 380: f(x)= 37.73382052919296
# differential_evolution step 381: f(x)= 37.73382052919296
# differential_evolution step 382: f(x)= 37.73382052919296
# differential_evolution step 383: f(x)= 37.7321169296847
# differential_evolution step 384: f(x)= 37.7321169296847
# differential_evolution step 385: f(x)= 37.7321169296847
# differential_evolution step 386: f(x)= 37.7321169296847
# differential_evolution step 387: f(x)= 37.7321169296847
# differential_evolution step 388: f(x)= 37.7321169296847
# differential_evolution step 389: f(x)= 37.7321169296847
# differential_evolution step 390: f(x)= 37.7321169296847
# differential_evolution step 391: f(x)= 37.7321169296847
# differential_evolution step 392: f(x)= 37.7321169296847
# differential_evolution step 393: f(x)= 37.7321169296847
# differential_evolution step 394: f(x)= 37.7321169296847
# differential_evolution step 395: f(x)= 37.7321169296847
# differential_evolution step 396: f(x)= 37.7321169296847
# differential_evolution step 397: f(x)= 37.731681027584315
# differential_evolution step 398: f(x)= 37.731681027584315
# differential_evolution step 399: f(x)= 37.731681027584315
# differential_evolution step 400: f(x)= 37.73040919987355
# differential_evolution step 401: f(x)= 37.73040919987355
# differential_evolution step 402: f(x)= 37.73040919987355
# differential_evolution step 403: f(x)= 37.73040919987355
# differential_evolution step 404: f(x)= 37.727042810507676
# differential_evolution step 405: f(x)= 37.727042810507676
# differential_evolution step 406: f(x)= 37.727042810507676
# differential_evolution step 407: f(x)= 37.727042810507676
# differential_evolution step 408: f(x)= 37.72690255976956
# differential_evolution step 409: f(x)= 37.72690255976956
# differential_evolution step 410: f(x)= 37.72690255976956
# differential_evolution step 411: f(x)= 37.72463978523487
# differential_evolution step 412: f(x)= 37.72463978523487
# differential_evolution step 413: f(x)= 37.72463978523487
# differential_evolution step 414: f(x)= 37.72463978523487
# differential_evolution step 415: f(x)= 37.72463978523487
# differential_evolution step 416: f(x)= 37.72463978523487
# differential_evolution step 417: f(x)= 37.72441043980625
# differential_evolution step 418: f(x)= 37.704374250466486
# differential_evolution step 419: f(x)= 37.704374250466486
# differential_evolution step 420: f(x)= 37.704374250466486
# differential_evolution step 421: f(x)= 37.704374250466486
# differential_evolution step 422: f(x)= 37.704374250466486
# differential_evolution step 423: f(x)= 37.704374250466486
# differential_evolution step 424: f(x)= 37.704374250466486
# differential_evolution step 425: f(x)= 37.704374250466486
# differential_evolution step 426: f(x)= 37.704374250466486
# differential_evolution step 427: f(x)= 37.704374250466486
# differential_evolution step 428: f(x)= 37.70349473378891
# differential_evolution step 429: f(x)= 37.70349473378891
# differential_evolution step 430: f(x)= 37.70349473378891
# differential_evolution step 431: f(x)= 37.70236562247851
# differential_evolution step 432: f(x)= 37.70236562247851
# differential_evolution step 433: f(x)= 37.70236562247851
# differential_evolution step 434: f(x)= 37.70236562247851
# differential_evolution step 435: f(x)= 37.70236562247851
# differential_evolution step 436: f(x)= 37.70236562247851
# differential_evolution step 437: f(x)= 37.70236562247851
# differential_evolution step 438: f(x)= 37.70075962519274
# differential_evolution step 439: f(x)= 37.70075962519274
# differential_evolution step 440: f(x)= 37.69652458570366
# differential_evolution step 441: f(x)= 37.69652458570366
# differential_evolution step 442: f(x)= 37.69652458570366
# differential_evolution step 443: f(x)= 37.69652458570366
# differential_evolution step 444: f(x)= 37.69652458570366
# differential_evolution step 445: f(x)= 37.69652458570366
# differential_evolution step 446: f(x)= 37.69344076016279
# differential_evolution step 447: f(x)= 37.69344076016279
# differential_evolution step 448: f(x)= 37.69344076016279
# differential_evolution step 449: f(x)= 37.69344076016279
# differential_evolution step 450: f(x)= 37.69344076016279
# differential_evolution step 451: f(x)= 37.69128393921587
# differential_evolution step 452: f(x)= 37.69128393921587
# differential_evolution step 453: f(x)= 37.69128393921587
# differential_evolution step 454: f(x)= 37.69128393921587
# differential_evolution step 455: f(x)= 37.69085313852593
# differential_evolution step 456: f(x)= 37.68521903145518
# differential_evolution step 457: f(x)= 37.68521903145518
# differential_evolution step 458: f(x)= 37.68521903145518
# differential_evolution step 459: f(x)= 37.68521903145518
# differential_evolution step 460: f(x)= 37.68521903145518
# differential_evolution step 461: f(x)= 37.68521903145518
# differential_evolution step 462: f(x)= 37.68405781731268
# differential_evolution step 463: f(x)= 37.68405781731268
# differential_evolution step 464: f(x)= 37.68405781731268
# differential_evolution step 465: f(x)= 37.68215826983773
# differential_evolution step 466: f(x)= 37.67729577709068
# differential_evolution step 467: f(x)= 37.67729577709068
# differential_evolution step 468: f(x)= 37.67729577709068
# differential_evolution step 469: f(x)= 37.67729577709068
# differential_evolution step 470: f(x)= 37.67729577709068
# differential_evolution step 471: f(x)= 37.67729577709068
# differential_evolution step 472: f(x)= 37.67729577709068
# differential_evolution step 473: f(x)= 37.67729577709068
# differential_evolution step 474: f(x)= 37.67729577709068
# differential_evolution step 475: f(x)= 37.67729577709068
# differential_evolution step 476: f(x)= 37.67729577709068
# differential_evolution step 477: f(x)= 37.67729577709068
# differential_evolution step 478: f(x)= 37.67729577709068
# differential_evolution step 479: f(x)= 37.673375337739785
# differential_evolution step 480: f(x)= 37.673375337739785
# differential_evolution step 481: f(x)= 37.671022493901106
# differential_evolution step 482: f(x)= 37.671022493901106
# differential_evolution step 483: f(x)= 37.671022493901106
# differential_evolution step 484: f(x)= 37.671022493901106
# differential_evolution step 485: f(x)= 37.671022493901106
# differential_evolution step 486: f(x)= 37.671022493901106
# differential_evolution step 487: f(x)= 37.671022493901106
# differential_evolution step 488: f(x)= 37.671022493901106
# differential_evolution step 489: f(x)= 37.66981469567711
# differential_evolution step 490: f(x)= 37.66981469567711
# differential_evolution step 491: f(x)= 37.66981469567711
# differential_evolution step 492: f(x)= 37.66981469567711
# differential_evolution step 493: f(x)= 37.66981469567711
# differential_evolution step 494: f(x)= 37.66981469567711
# differential_evolution step 495: f(x)= 37.66981469567711
# differential_evolution step 496: f(x)= 37.66981469567711
# differential_evolution step 497: f(x)= 37.66981469567711
# differential_evolution step 498: f(x)= 37.66894812225276
# differential_evolution step 499: f(x)= 37.66894812225276
# differential_evolution step 500: f(x)= 37.66894812225276
# differential_evolution step 501: f(x)= 37.66894812225276
# differential_evolution step 502: f(x)= 37.666514613338485
# differential_evolution step 503: f(x)= 37.666514613338485
# differential_evolution step 504: f(x)= 37.666514613338485
# differential_evolution step 505: f(x)= 37.666514613338485
# differential_evolution step 506: f(x)= 37.66634690942612
# differential_evolution step 507: f(x)= 37.66634690942612
# differential_evolution step 508: f(x)= 37.66634690942612
# differential_evolution step 509: f(x)= 37.66634690942612
# differential_evolution step 510: f(x)= 37.6657275370974
# differential_evolution step 511: f(x)= 37.6657275370974
# differential_evolution step 512: f(x)= 37.66353618470524
# differential_evolution step 513: f(x)= 37.66353618470524
# differential_evolution step 514: f(x)= 37.66353618470524
# differential_evolution step 515: f(x)= 37.66353618470524
# differential_evolution step 516: f(x)= 37.66353618470524
# differential_evolution step 517: f(x)= 37.66353618470524
# differential_evolution step 518: f(x)= 37.66353618470524
# differential_evolution step 519: f(x)= 37.66353618470524
# differential_evolution step 520: f(x)= 37.66188097750204
# differential_evolution step 521: f(x)= 37.66188097750204
# differential_evolution step 522: f(x)= 37.66188097750204
# differential_evolution step 523: f(x)= 37.66188097750204
# differential_evolution step 524: f(x)= 37.66188097750204
# differential_evolution step 525: f(x)= 37.66188097750204
# differential_evolution step 526: f(x)= 37.66188097750204
# differential_evolution step 527: f(x)= 37.66188097750204
# differential_evolution step 528: f(x)= 37.66188097750204
# differential_evolution step 529: f(x)= 37.65942029943751
# differential_evolution step 530: f(x)= 37.65942029943751
# differential_evolution step 531: f(x)= 37.65942029943751
# differential_evolution step 532: f(x)= 37.65942029943751
# differential_evolution step 533: f(x)= 37.65899372210219
# differential_evolution step 534: f(x)= 37.65899372210219
# differential_evolution step 535: f(x)= 37.65899372210219
# differential_evolution step 536: f(x)= 37.65899372210219
# differential_evolution step 537: f(x)= 37.65899372210219
# differential_evolution step 538: f(x)= 37.65899372210219
# differential_evolution step 539: f(x)= 37.65899372210219
# differential_evolution step 540: f(x)= 37.658425778892074
# differential_evolution step 541: f(x)= 37.658425778892074
# differential_evolution step 542: f(x)= 37.65842077300975
# differential_evolution step 543: f(x)= 37.65842077300975
# differential_evolution step 544: f(x)= 37.65842077300975
# differential_evolution step 545: f(x)= 37.65842077300975
# differential_evolution step 546: f(x)= 37.65842077300975
# differential_evolution step 547: f(x)= 37.657362508170806
# differential_evolution step 548: f(x)= 37.657362508170806
# differential_evolution step 549: f(x)= 37.657362508170806
# differential_evolution step 550: f(x)= 37.657362508170806
# differential_evolution step 551: f(x)= 37.657362508170806
# differential_evolution step 552: f(x)= 37.657362508170806
# differential_evolution step 553: f(x)= 37.657362508170806
# differential_evolution step 554: f(x)= 37.657362508170806
# differential_evolution step 555: f(x)= 37.657362508170806
# differential_evolution step 556: f(x)= 37.657362508170806
# differential_evolution step 557: f(x)= 37.657362508170806
# differential_evolution step 558: f(x)= 37.65727429738876
# differential_evolution step 559: f(x)= 37.65706974729095
# differential_evolution step 560: f(x)= 37.65706974729095
# differential_evolution step 561: f(x)= 37.656702160261034
# differential_evolution step 562: f(x)= 37.656702160261034
# differential_evolution step 563: f(x)= 37.656702160261034
# differential_evolution step 564: f(x)= 37.65532255650206
# differential_evolution step 565: f(x)= 37.65532255650206
# differential_evolution step 566: f(x)= 37.65532255650206
# differential_evolution step 567: f(x)= 37.65531093392576
# differential_evolution step 568: f(x)= 37.655066734502284
# differential_evolution step 569: f(x)= 37.655066734502284
# differential_evolution step 570: f(x)= 37.655066734502284
# differential_evolution step 571: f(x)= 37.655066734502284
# differential_evolution step 572: f(x)= 37.65429569443876
# differential_evolution step 573: f(x)= 37.65429569443876
# differential_evolution step 574: f(x)= 37.653970409951086
# differential_evolution step 575: f(x)= 37.653970409951086
# differential_evolution step 576: f(x)= 37.653970409951086
# differential_evolution step 577: f(x)= 37.653970409951086
# differential_evolution step 578: f(x)= 37.653970409951086
# differential_evolution step 579: f(x)= 37.653970409951086
# differential_evolution step 580: f(x)= 37.653970409951086
# differential_evolution step 581: f(x)= 37.65249673134531
# differential_evolution step 582: f(x)= 37.65249673134531
# differential_evolution step 583: f(x)= 37.65249673134531
# differential_evolution step 584: f(x)= 37.65249673134531
# differential_evolution step 585: f(x)= 37.65249673134531
# differential_evolution step 586: f(x)= 37.65249673134531
# differential_evolution step 587: f(x)= 37.65249673134531
# differential_evolution step 588: f(x)= 37.65249673134531
# differential_evolution step 589: f(x)= 37.65249673134531
# differential_evolution step 590: f(x)= 37.65249673134531
# differential_evolution step 591: f(x)= 37.65249673134531
# differential_evolution step 592: f(x)= 37.65249673134531
# differential_evolution step 593: f(x)= 37.65249673134531
# differential_evolution step 594: f(x)= 37.65249673134531
# differential_evolution step 595: f(x)= 37.65144264024887
# differential_evolution step 596: f(x)= 37.65144264024887
# differential_evolution step 597: f(x)= 37.65144264024887
# differential_evolution step 598: f(x)= 37.65144264024887
# differential_evolution step 599: f(x)= 37.65144264024887
# differential_evolution step 600: f(x)= 37.65144264024887
# differential_evolution step 601: f(x)= 37.65144264024887
# differential_evolution step 602: f(x)= 37.65144264024887
# differential_evolution step 603: f(x)= 37.65144264024887
# differential_evolution step 604: f(x)= 37.65144264024887
# differential_evolution step 605: f(x)= 37.651125630098015
# differential_evolution step 606: f(x)= 37.651125630098015
# differential_evolution step 607: f(x)= 37.651125630098015
# differential_evolution step 608: f(x)= 37.651125630098015
# differential_evolution step 609: f(x)= 37.651125630098015
# differential_evolution step 610: f(x)= 37.651125630098015
# differential_evolution step 611: f(x)= 37.651125630098015
# differential_evolution step 612: f(x)= 37.651125630098015
# differential_evolution step 613: f(x)= 37.651125630098015
# differential_evolution step 614: f(x)= 37.651125630098015
# differential_evolution step 615: f(x)= 37.65071331649473
# differential_evolution step 616: f(x)= 37.65071331649473
# differential_evolution step 617: f(x)= 37.64953668326501
# differential_evolution step 618: f(x)= 37.64953668326501
# differential_evolution step 619: f(x)= 37.64953668326501
# differential_evolution step 620: f(x)= 37.64953668326501
# differential_evolution step 621: f(x)= 37.64953668326501
# differential_evolution step 622: f(x)= 37.64953668326501
# differential_evolution step 623: f(x)= 37.64953668326501
# differential_evolution step 624: f(x)= 37.64953668326501
# differential_evolution step 625: f(x)= 37.64953668326501
# differential_evolution step 626: f(x)= 37.64953668326501
# differential_evolution step 627: f(x)= 37.64953668326501
# differential_evolution step 628: f(x)= 37.64953668326501
# differential_evolution step 629: f(x)= 37.64953668326501
# differential_evolution step 630: f(x)= 37.64953668326501
# differential_evolution step 631: f(x)= 37.64953668326501
# differential_evolution step 632: f(x)= 37.64953668326501
# differential_evolution step 633: f(x)= 37.64953668326501
# differential_evolution step 634: f(x)= 37.649337985304726
# differential_evolution step 635: f(x)= 37.649337985304726
# differential_evolution step 636: f(x)= 37.649337985304726
# differential_evolution step 637: f(x)= 37.64928654909735
# differential_evolution step 638: f(x)= 37.64928654909735
# differential_evolution step 639: f(x)= 37.64928654909735
# differential_evolution step 640: f(x)= 37.64928654909735
# differential_evolution step 641: f(x)= 37.64928654909735
# differential_evolution step 642: f(x)= 37.64928654909735
# differential_evolution step 643: f(x)= 37.649230992058726
# differential_evolution step 644: f(x)= 37.649230992058726
# differential_evolution step 645: f(x)= 37.649230992058726
# differential_evolution step 646: f(x)= 37.649230992058726
# differential_evolution step 647: f(x)= 37.649230992058726
# differential_evolution step 648: f(x)= 37.649208023616254
# differential_evolution step 649: f(x)= 37.649208023616254
# differential_evolution step 650: f(x)= 37.649208023616254
# differential_evolution step 651: f(x)= 37.64915884218294
# differential_evolution step 652: f(x)= 37.64876518581506
# differential_evolution step 653: f(x)= 37.64876518581506
# differential_evolution step 654: f(x)= 37.64876518581506
# differential_evolution step 655: f(x)= 37.64876518581506
# differential_evolution step 656: f(x)= 37.64876518581506
# differential_evolution step 657: f(x)= 37.64876518581506
# differential_evolution step 658: f(x)= 37.64876518581506
# differential_evolution step 659: f(x)= 37.64876518581506
# differential_evolution step 660: f(x)= 37.64861441213491
# differential_evolution step 661: f(x)= 37.64861441213491
# differential_evolution step 662: f(x)= 37.64861441213491
# differential_evolution step 663: f(x)= 37.64861441213491
# differential_evolution step 664: f(x)= 37.64861441213491
# differential_evolution step 665: f(x)= 37.64861441213491
# differential_evolution step 666: f(x)= 37.6485843999535
# differential_evolution step 667: f(x)= 37.6485843999535
# differential_evolution step 668: f(x)= 37.64850702865215
# differential_evolution step 669: f(x)= 37.64850702865215
# differential_evolution step 670: f(x)= 37.64850702865215
# differential_evolution step 671: f(x)= 37.64850702865215
# differential_evolution step 672: f(x)= 37.64847776311049
# differential_evolution step 673: f(x)= 37.648367325146765
# differential_evolution step 674: f(x)= 37.648367325146765
# differential_evolution step 675: f(x)= 37.648367325146765
# differential_evolution step 676: f(x)= 37.648367325146765
# differential_evolution step 677: f(x)= 37.648301742222095
# differential_evolution step 678: f(x)= 37.648301742222095
# differential_evolution step 679: f(x)= 37.648301742222095
# differential_evolution step 680: f(x)= 37.648301742222095
# differential_evolution step 681: f(x)= 37.64825853719415
# differential_evolution step 682: f(x)= 37.64825853719415
# differential_evolution step 683: f(x)= 37.64825853719415
# differential_evolution step 684: f(x)= 37.64825853719415
# differential_evolution step 685: f(x)= 37.64825853719415
# differential_evolution step 686: f(x)= 37.64825853719415
# differential_evolution step 687: f(x)= 37.64825853719415
# differential_evolution step 688: f(x)= 37.6482259767013
# differential_evolution step 689: f(x)= 37.648179166604045
# differential_evolution step 690: f(x)= 37.648179166604045
# differential_evolution step 691: f(x)= 37.648179166604045
# differential_evolution step 692: f(x)= 37.648179166604045
# differential_evolution step 693: f(x)= 37.648179166604045
# differential_evolution step 694: f(x)= 37.648179166604045
# differential_evolution step 695: f(x)= 37.648179166604045
# differential_evolution step 696: f(x)= 37.64815780521864
# differential_evolution step 697: f(x)= 37.64812140591662
# differential_evolution step 698: f(x)= 37.64812140591662
# differential_evolution step 699: f(x)= 37.64812140591662
# differential_evolution step 700: f(x)= 37.64812140591662
# differential_evolution step 701: f(x)= 37.648022697982604
# differential_evolution step 702: f(x)= 37.648022697982604
# differential_evolution step 703: f(x)= 37.648022697982604
# differential_evolution step 704: f(x)= 37.648022697982604
# differential_evolution step 705: f(x)= 37.648022697982604
# differential_evolution step 706: f(x)= 37.648022697982604
# differential_evolution step 707: f(x)= 37.648022697982604
# differential_evolution step 708: f(x)= 37.648022697982604
# differential_evolution step 709: f(x)= 37.648022697982604
# differential_evolution step 710: f(x)= 37.648022697982604
# differential_evolution step 711: f(x)= 37.648022697982604
# differential_evolution step 712: f(x)= 37.648022697982604
# differential_evolution step 713: f(x)= 37.648022697982604
# differential_evolution step 714: f(x)= 37.648022697982604
# differential_evolution step 715: f(x)= 37.648022697982604
# differential_evolution step 716: f(x)= 37.648022697982604
# differential_evolution step 717: f(x)= 37.648022697982604
# differential_evolution step 718: f(x)= 37.648022697982604
# differential_evolution step 719: f(x)= 37.648022697982604
# differential_evolution step 720: f(x)= 37.648022697982604
# differential_evolution step 721: f(x)= 37.648022697982604
# differential_evolution step 722: f(x)= 37.64801526847367
# differential_evolution step 723: f(x)= 37.64801526847367
# differential_evolution step 724: f(x)= 37.64801526847367
# differential_evolution step 725: f(x)= 37.64801526847367
# differential_evolution step 726: f(x)= 37.64801526847367
# differential_evolution step 727: f(x)= 37.64801526847367
# differential_evolution step 728: f(x)= 37.64801526847367
# differential_evolution step 729: f(x)= 37.648008613507585
# differential_evolution step 730: f(x)= 37.648008613507585
# differential_evolution step 731: f(x)= 37.64797036178685
# differential_evolution step 732: f(x)= 37.64797036178685
# differential_evolution step 733: f(x)= 37.64797036178685
# differential_evolution step 734: f(x)= 37.64797036178685
# differential_evolution step 735: f(x)= 37.64796598359158
# differential_evolution step 736: f(x)= 37.64794939228368
# differential_evolution step 737: f(x)= 37.64794939228368
# differential_evolution step 738: f(x)= 37.64794939228368
# differential_evolution step 739: f(x)= 37.64793417698428
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=10.8940, n=2.1765, x_0=38.2362
# Sérsic 2: I_e=0.0374, r_e=49.9988, n=3.4567, x_0=48.4974
# Sérsic 3: I_e=0.0290, r_e=49.9993, n=3.6510, x_0=81.0023
# Chi quadro minimo: 37.64793417698428
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII, r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')

# %%
params_curve_OIII, covariance_OIII = curve_fit(model_convolved, x_axes, radial_profile_OIII, p0=result.x, sigma = radial_profile_error_OIII)

chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, radial_profile_error_OIII,
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_19040\2374069783.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_19040\2374069783.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Sérsic 1: I_e=6.2864, r_e=2.6428, n=0.8743, x_0=38.0026
# Sérsic 2: I_e=0.0039, r_e=1277.9777, n=4.6600, x_0=48.4974
# Sérsic 3: I_e=0.3853, r_e=3.7544, n=2.0991, x_0=81.0018
# [9.55969764e-01 2.13329373e-01 1.20700341e-01 6.32093485e-02
#  1.65452471e-02 4.48356560e+03 3.14796777e+00 3.10027014e-04
#  6.55319883e-01 4.00797369e+00 1.57474941e+00 1.31444447e-01]
# 78.58644496949054

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 53914.64009047337
# differential_evolution step 2: f(x)= 48395.99412989204
# differential_evolution step 3: f(x)= 42340.407762573646
# differential_evolution step 4: f(x)= 40685.54851246917
# differential_evolution step 5: f(x)= 38476.201436821866
# differential_evolution step 6: f(x)= 37800.31790269893
# differential_evolution step 7: f(x)= 31150.465723474234
# differential_evolution step 8: f(x)= 31150.465723474234
# differential_evolution step 9: f(x)= 31150.465723474234
# differential_evolution step 10: f(x)= 30295.734635378492
# differential_evolution step 11: f(x)= 30295.734635378492
# differential_evolution step 12: f(x)= 27090.058457347623
# differential_evolution step 13: f(x)= 27090.058457347623
# differential_evolution step 14: f(x)= 27090.058457347623
# differential_evolution step 15: f(x)= 27090.058457347623
# differential_evolution step 16: f(x)= 27090.058457347623
# differential_evolution step 17: f(x)= 27090.058457347623
# differential_evolution step 18: f(x)= 27090.058457347623
# differential_evolution step 19: f(x)= 27090.058457347623
# differential_evolution step 20: f(x)= 27090.058457347623
# differential_evolution step 21: f(x)= 27090.058457347623
# differential_evolution step 22: f(x)= 27090.058457347623
# differential_evolution step 23: f(x)= 27090.058457347623
# differential_evolution step 24: f(x)= 27090.058457347623
# differential_evolution step 25: f(x)= 27090.058457347623
# differential_evolution step 26: f(x)= 27090.058457347623
# differential_evolution step 27: f(x)= 27090.058457347623
# differential_evolution step 28: f(x)= 26241.95576273252
# differential_evolution step 29: f(x)= 26241.95576273252
# differential_evolution step 30: f(x)= 26241.95576273252
# differential_evolution step 31: f(x)= 26241.95576273252
# differential_evolution step 32: f(x)= 26241.95576273252
# differential_evolution step 33: f(x)= 25602.56844262997
# differential_evolution step 34: f(x)= 25602.56844262997
# differential_evolution step 35: f(x)= 25602.56844262997
# differential_evolution step 36: f(x)= 24265.253929168695
# differential_evolution step 37: f(x)= 24265.253929168695
# differential_evolution step 38: f(x)= 24265.253929168695
# differential_evolution step 39: f(x)= 24265.253929168695
# differential_evolution step 40: f(x)= 24265.253929168695
# differential_evolution step 41: f(x)= 24265.253929168695
# differential_evolution step 42: f(x)= 24265.253929168695
# differential_evolution step 43: f(x)= 22518.881069401403
# differential_evolution step 44: f(x)= 22518.881069401403
# differential_evolution step 45: f(x)= 22518.881069401403
# differential_evolution step 46: f(x)= 22518.881069401403
# differential_evolution step 47: f(x)= 22518.881069401403
# differential_evolution step 48: f(x)= 22518.881069401403
# differential_evolution step 49: f(x)= 22518.881069401403
# differential_evolution step 50: f(x)= 22518.881069401403
# differential_evolution step 51: f(x)= 22518.881069401403
# differential_evolution step 52: f(x)= 22518.881069401403
# differential_evolution step 53: f(x)= 22518.881069401403
# differential_evolution step 54: f(x)= 22518.881069401403
# differential_evolution step 55: f(x)= 22518.881069401403
# differential_evolution step 56: f(x)= 22518.881069401403
# differential_evolution step 57: f(x)= 22518.881069401403
# differential_evolution step 58: f(x)= 22518.881069401403
# differential_evolution step 59: f(x)= 22518.881069401403
# differential_evolution step 60: f(x)= 22518.881069401403
# differential_evolution step 61: f(x)= 22518.881069401403
# differential_evolution step 62: f(x)= 22518.881069401403
# differential_evolution step 63: f(x)= 22008.36096066401
# differential_evolution step 64: f(x)= 21274.871786797623
# differential_evolution step 65: f(x)= 21274.871786797623
# differential_evolution step 66: f(x)= 21274.871786797623
# differential_evolution step 67: f(x)= 21274.871786797623
# differential_evolution step 68: f(x)= 21188.392891850686
# differential_evolution step 69: f(x)= 21188.392891850686
# differential_evolution step 70: f(x)= 21188.392891850686
# differential_evolution step 71: f(x)= 21188.392891850686
# differential_evolution step 72: f(x)= 20903.929076005552
# differential_evolution step 73: f(x)= 20903.929076005552
# differential_evolution step 74: f(x)= 20903.929076005552
# differential_evolution step 75: f(x)= 20903.929076005552
# differential_evolution step 76: f(x)= 19974.59716725346
# differential_evolution step 77: f(x)= 19974.59716725346
# differential_evolution step 78: f(x)= 19974.59716725346
# differential_evolution step 79: f(x)= 19974.59716725346
# differential_evolution step 80: f(x)= 19974.59716725346
# differential_evolution step 81: f(x)= 19974.59716725346
# differential_evolution step 82: f(x)= 19974.59716725346
# differential_evolution step 83: f(x)= 19974.59716725346
# differential_evolution step 84: f(x)= 19974.59716725346
# differential_evolution step 85: f(x)= 19974.59716725346
# differential_evolution step 86: f(x)= 19974.59716725346
# differential_evolution step 87: f(x)= 19974.59716725346
# differential_evolution step 88: f(x)= 19974.59716725346
# differential_evolution step 89: f(x)= 19974.59716725346
# differential_evolution step 90: f(x)= 19974.59716725346
# differential_evolution step 91: f(x)= 19974.59716725346
# differential_evolution step 92: f(x)= 19974.59716725346
# differential_evolution step 93: f(x)= 19974.59716725346
# differential_evolution step 94: f(x)= 19974.59716725346
# differential_evolution step 95: f(x)= 19974.59716725346
# differential_evolution step 96: f(x)= 19974.59716725346
# differential_evolution step 97: f(x)= 19974.59716725346
# differential_evolution step 98: f(x)= 19974.59716725346
# differential_evolution step 99: f(x)= 19974.59716725346
# differential_evolution step 100: f(x)= 19974.59716725346
# differential_evolution step 101: f(x)= 19974.59716725346
# differential_evolution step 102: f(x)= 19974.59716725346
# differential_evolution step 103: f(x)= 19974.59716725346
# differential_evolution step 104: f(x)= 19974.59716725346
# differential_evolution step 105: f(x)= 19974.59716725346
# differential_evolution step 106: f(x)= 19974.59716725346
# differential_evolution step 107: f(x)= 19974.59716725346
# differential_evolution step 108: f(x)= 19974.59716725346
# differential_evolution step 109: f(x)= 19974.59716725346
# differential_evolution step 110: f(x)= 19221.781573189455
# differential_evolution step 111: f(x)= 19221.781573189455
# differential_evolution step 112: f(x)= 19221.781573189455
# differential_evolution step 113: f(x)= 19221.781573189455
# differential_evolution step 114: f(x)= 19221.781573189455
# differential_evolution step 115: f(x)= 19221.781573189455
# differential_evolution step 116: f(x)= 19221.781573189455
# differential_evolution step 117: f(x)= 19221.781573189455
# differential_evolution step 118: f(x)= 19221.781573189455
# differential_evolution step 119: f(x)= 19221.781573189455
# differential_evolution step 120: f(x)= 19221.781573189455
# differential_evolution step 121: f(x)= 19221.781573189455
# differential_evolution step 122: f(x)= 19221.781573189455
# differential_evolution step 123: f(x)= 19221.781573189455
# differential_evolution step 124: f(x)= 19221.781573189455
# differential_evolution step 125: f(x)= 19221.781573189455
# differential_evolution step 126: f(x)= 19221.781573189455
# differential_evolution step 127: f(x)= 19221.781573189455
# differential_evolution step 128: f(x)= 19221.781573189455
# differential_evolution step 129: f(x)= 19221.781573189455
# differential_evolution step 130: f(x)= 19221.781573189455
# differential_evolution step 131: f(x)= 19221.781573189455
# differential_evolution step 132: f(x)= 19221.781573189455
# differential_evolution step 133: f(x)= 19221.781573189455
# differential_evolution step 134: f(x)= 19221.781573189455
# differential_evolution step 135: f(x)= 19221.781573189455
# differential_evolution step 136: f(x)= 19221.781573189455
# differential_evolution step 137: f(x)= 19221.781573189455
# differential_evolution step 138: f(x)= 19221.781573189455
# differential_evolution step 139: f(x)= 19221.781573189455
# differential_evolution step 140: f(x)= 19221.781573189455
# differential_evolution step 141: f(x)= 19221.781573189455
# differential_evolution step 142: f(x)= 19221.781573189455
# differential_evolution step 143: f(x)= 19221.781573189455
# differential_evolution step 144: f(x)= 19221.781573189455
# differential_evolution step 145: f(x)= 19221.781573189455
# differential_evolution step 146: f(x)= 19221.781573189455
# differential_evolution step 147: f(x)= 19221.781573189455
# differential_evolution step 148: f(x)= 19221.781573189455
# differential_evolution step 149: f(x)= 18853.02114483047
# differential_evolution step 150: f(x)= 18853.02114483047
# differential_evolution step 151: f(x)= 18853.02114483047
# differential_evolution step 152: f(x)= 18853.02114483047
# differential_evolution step 153: f(x)= 18853.02114483047
# differential_evolution step 154: f(x)= 18620.324307025203
# differential_evolution step 155: f(x)= 18620.324307025203
# differential_evolution step 156: f(x)= 18620.324307025203
# differential_evolution step 157: f(x)= 18620.324307025203
# differential_evolution step 158: f(x)= 18620.324307025203
# differential_evolution step 159: f(x)= 18620.324307025203
# differential_evolution step 160: f(x)= 18620.324307025203
# differential_evolution step 161: f(x)= 18620.324307025203
# differential_evolution step 162: f(x)= 18620.324307025203
# differential_evolution step 163: f(x)= 18620.324307025203
# differential_evolution step 164: f(x)= 18620.324307025203
# differential_evolution step 165: f(x)= 18620.324307025203
# differential_evolution step 166: f(x)= 18620.324307025203
# differential_evolution step 167: f(x)= 18620.324307025203
# differential_evolution step 168: f(x)= 18189.552943294893
# differential_evolution step 169: f(x)= 18189.552943294893
# differential_evolution step 170: f(x)= 18189.552943294893
# differential_evolution step 171: f(x)= 18189.552943294893
# differential_evolution step 172: f(x)= 18189.552943294893
# differential_evolution step 173: f(x)= 18189.552943294893
# differential_evolution step 174: f(x)= 18189.552943294893
# differential_evolution step 175: f(x)= 18189.552943294893
# differential_evolution step 176: f(x)= 18189.552943294893
# differential_evolution step 177: f(x)= 18189.552943294893
# differential_evolution step 178: f(x)= 18189.552943294893
# differential_evolution step 179: f(x)= 18189.552943294893
# differential_evolution step 180: f(x)= 18189.552943294893
# differential_evolution step 181: f(x)= 18189.552943294893
# differential_evolution step 182: f(x)= 18189.552943294893
# differential_evolution step 183: f(x)= 18189.552943294893
# differential_evolution step 184: f(x)= 18189.552943294893
# differential_evolution step 185: f(x)= 18189.552943294893
# differential_evolution step 186: f(x)= 18189.552943294893
# differential_evolution step 187: f(x)= 18189.552943294893
# differential_evolution step 188: f(x)= 18189.552943294893
# differential_evolution step 189: f(x)= 18189.552943294893
# differential_evolution step 190: f(x)= 18189.552943294893
# differential_evolution step 191: f(x)= 18189.552943294893
# differential_evolution step 192: f(x)= 18189.552943294893
# differential_evolution step 193: f(x)= 18189.552943294893
# differential_evolution step 194: f(x)= 18189.552943294893
# differential_evolution step 195: f(x)= 18189.552943294893
# differential_evolution step 196: f(x)= 18189.552943294893
# differential_evolution step 197: f(x)= 18189.552943294893
# differential_evolution step 198: f(x)= 18152.364458953853
# differential_evolution step 199: f(x)= 18152.364458953853
# differential_evolution step 200: f(x)= 18152.364458953853
# differential_evolution step 201: f(x)= 18152.364458953853
# differential_evolution step 202: f(x)= 18152.364458953853
# differential_evolution step 203: f(x)= 18062.176762354247
# differential_evolution step 204: f(x)= 18062.176762354247
# differential_evolution step 205: f(x)= 17925.0056587787
# differential_evolution step 206: f(x)= 17805.487140081666
# differential_evolution step 207: f(x)= 17747.059986748867
# differential_evolution step 208: f(x)= 17747.059986748867
# differential_evolution step 209: f(x)= 17668.034907500467
# differential_evolution step 210: f(x)= 17601.230677410873
# differential_evolution step 211: f(x)= 17257.477527019633
# differential_evolution step 212: f(x)= 17257.477527019633
# differential_evolution step 213: f(x)= 17257.477527019633
# differential_evolution step 214: f(x)= 17204.43134299721
# differential_evolution step 215: f(x)= 17204.43134299721
# differential_evolution step 216: f(x)= 17204.43134299721
# differential_evolution step 217: f(x)= 16904.846808186863
# differential_evolution step 218: f(x)= 16904.846808186863
# differential_evolution step 219: f(x)= 16904.846808186863
# differential_evolution step 220: f(x)= 16904.846808186863
# differential_evolution step 221: f(x)= 16904.846808186863
# differential_evolution step 222: f(x)= 16904.846808186863
# differential_evolution step 223: f(x)= 16904.846808186863
# differential_evolution step 224: f(x)= 16904.846808186863
# differential_evolution step 225: f(x)= 16894.64930992871
# differential_evolution step 226: f(x)= 16887.413749335683
# differential_evolution step 227: f(x)= 16887.413749335683
# differential_evolution step 228: f(x)= 16887.413749335683
# differential_evolution step 229: f(x)= 16887.413749335683
# differential_evolution step 230: f(x)= 16887.413749335683
# differential_evolution step 231: f(x)= 16887.413749335683
# differential_evolution step 232: f(x)= 16887.413749335683
# differential_evolution step 233: f(x)= 16887.413749335683
# differential_evolution step 234: f(x)= 16887.413749335683
# differential_evolution step 235: f(x)= 16887.413749335683
# differential_evolution step 236: f(x)= 16887.413749335683
# differential_evolution step 237: f(x)= 16833.655707500297
# differential_evolution step 238: f(x)= 16833.655707500297
# differential_evolution step 239: f(x)= 16833.655707500297
# differential_evolution step 240: f(x)= 16833.655707500297
# differential_evolution step 241: f(x)= 16833.655707500297
# differential_evolution step 242: f(x)= 16833.655707500297
# differential_evolution step 243: f(x)= 16746.943891628118
# differential_evolution step 244: f(x)= 16746.943891628118
# differential_evolution step 245: f(x)= 16746.943891628118
# differential_evolution step 246: f(x)= 16746.943891628118
# differential_evolution step 247: f(x)= 16746.943891628118
# differential_evolution step 248: f(x)= 16714.175048589128
# differential_evolution step 249: f(x)= 16714.175048589128
# differential_evolution step 250: f(x)= 16714.175048589128
# differential_evolution step 251: f(x)= 16655.113617089675
# differential_evolution step 252: f(x)= 16655.113617089675
# differential_evolution step 253: f(x)= 16655.113617089675
# differential_evolution step 254: f(x)= 16633.90432324232
# differential_evolution step 255: f(x)= 16633.90432324232
# differential_evolution step 256: f(x)= 16633.90432324232
# differential_evolution step 257: f(x)= 16633.90432324232
# differential_evolution step 258: f(x)= 16633.90432324232
# differential_evolution step 259: f(x)= 16633.90432324232
# differential_evolution step 260: f(x)= 16633.90432324232
# differential_evolution step 261: f(x)= 16625.896589432847
# differential_evolution step 262: f(x)= 16625.896589432847
# differential_evolution step 263: f(x)= 16622.80746781447
# differential_evolution step 264: f(x)= 16622.80746781447
# differential_evolution step 265: f(x)= 16605.017866516082
# differential_evolution step 266: f(x)= 16573.077628585186
# differential_evolution step 267: f(x)= 16573.077628585186
# differential_evolution step 268: f(x)= 16573.077628585186
# differential_evolution step 269: f(x)= 16573.077628585186
# differential_evolution step 270: f(x)= 16573.077628585186
# differential_evolution step 271: f(x)= 16564.886559872306
# differential_evolution step 272: f(x)= 16564.886559872306
# differential_evolution step 273: f(x)= 16564.886559872306
# differential_evolution step 274: f(x)= 16564.886559872306
# differential_evolution step 275: f(x)= 16553.69934604095
# differential_evolution step 276: f(x)= 16553.69934604095
# differential_evolution step 277: f(x)= 16540.51491513303
# differential_evolution step 278: f(x)= 16533.80302866051
# differential_evolution step 279: f(x)= 16533.80302866051
# differential_evolution step 280: f(x)= 16513.452392450665
# differential_evolution step 281: f(x)= 16498.256753990376
# differential_evolution step 282: f(x)= 16498.256753990376
# differential_evolution step 283: f(x)= 16498.256753990376
# differential_evolution step 284: f(x)= 16497.09034468613
# differential_evolution step 285: f(x)= 16497.09034468613
# differential_evolution step 286: f(x)= 16461.325084311415
# differential_evolution step 287: f(x)= 16461.325084311415
# differential_evolution step 288: f(x)= 16461.325084311415
# differential_evolution step 289: f(x)= 16461.325084311415
# differential_evolution step 290: f(x)= 16461.325084311415
# differential_evolution step 291: f(x)= 16461.325084311415
# differential_evolution step 292: f(x)= 16447.996291586674
# differential_evolution step 293: f(x)= 16447.996291586674
# differential_evolution step 294: f(x)= 16447.996291586674
# differential_evolution step 295: f(x)= 16447.996291586674
# differential_evolution step 296: f(x)= 16447.996291586674
# differential_evolution step 297: f(x)= 16447.996291586674
# differential_evolution step 298: f(x)= 16447.996291586674
# differential_evolution step 299: f(x)= 16447.996291586674
# differential_evolution step 300: f(x)= 16447.9447374761
# differential_evolution step 301: f(x)= 16447.9447374761
# differential_evolution step 302: f(x)= 16447.9447374761
# differential_evolution step 303: f(x)= 16444.447753397846
# differential_evolution step 304: f(x)= 16432.454183871992
# differential_evolution step 305: f(x)= 16432.454183871992
# differential_evolution step 306: f(x)= 16432.454183871992
# differential_evolution step 307: f(x)= 16432.454183871992
# differential_evolution step 308: f(x)= 16432.454183871992
# differential_evolution step 309: f(x)= 16432.454183871992
# differential_evolution step 310: f(x)= 16432.454183871992
# differential_evolution step 311: f(x)= 16432.454183871992
# differential_evolution step 312: f(x)= 16409.508981449027
# differential_evolution step 313: f(x)= 16409.508981449027
# differential_evolution step 314: f(x)= 16409.508981449027
# differential_evolution step 315: f(x)= 16409.508981449027
# differential_evolution step 316: f(x)= 16409.508981449027
# differential_evolution step 317: f(x)= 16409.508981449027
# differential_evolution step 318: f(x)= 16409.508981449027
# differential_evolution step 319: f(x)= 16409.508981449027
# differential_evolution step 320: f(x)= 16409.508981449027
# differential_evolution step 321: f(x)= 16409.508981449027
# differential_evolution step 322: f(x)= 16390.80086175244
# differential_evolution step 323: f(x)= 16390.80086175244
# differential_evolution step 324: f(x)= 16390.80086175244
# differential_evolution step 325: f(x)= 16390.80086175244
# differential_evolution step 326: f(x)= 16390.80086175244
# differential_evolution step 327: f(x)= 16390.80086175244
# differential_evolution step 328: f(x)= 16390.80086175244
# differential_evolution step 329: f(x)= 16390.80086175244
# differential_evolution step 330: f(x)= 16390.80086175244
# differential_evolution step 331: f(x)= 16390.80086175244
# differential_evolution step 332: f(x)= 16390.80086175244
# differential_evolution step 333: f(x)= 16390.80086175244
# differential_evolution step 334: f(x)= 16390.80086175244
# differential_evolution step 335: f(x)= 16390.80086175244
# differential_evolution step 336: f(x)= 16390.80086175244
# differential_evolution step 337: f(x)= 16390.80086175244
# differential_evolution step 338: f(x)= 16390.80086175244
# differential_evolution step 339: f(x)= 16384.53631771932
# differential_evolution step 340: f(x)= 16384.53631771932
# differential_evolution step 341: f(x)= 16384.53631771932
# differential_evolution step 342: f(x)= 16384.53631771932
# differential_evolution step 343: f(x)= 16384.53631771932
# differential_evolution step 344: f(x)= 16384.53631771932
# differential_evolution step 345: f(x)= 16384.53631771932
# differential_evolution step 346: f(x)= 16384.53631771932
# differential_evolution step 347: f(x)= 16384.53631771932
# differential_evolution step 348: f(x)= 16384.53631771932
# differential_evolution step 349: f(x)= 16384.53631771932
# differential_evolution step 350: f(x)= 16384.53631771932
# differential_evolution step 351: f(x)= 16384.53631771932
# differential_evolution step 352: f(x)= 16383.75681049829
# differential_evolution step 353: f(x)= 16383.75681049829
# differential_evolution step 354: f(x)= 16383.75681049829
# differential_evolution step 355: f(x)= 16383.75681049829
# differential_evolution step 356: f(x)= 16378.004483280076
# differential_evolution step 357: f(x)= 16378.004483280076
# differential_evolution step 358: f(x)= 16378.004483280076
# differential_evolution step 359: f(x)= 16378.004483280076
# differential_evolution step 360: f(x)= 16373.774814501803
# differential_evolution step 361: f(x)= 16373.774814501803
# differential_evolution step 362: f(x)= 16373.774814501803
# differential_evolution step 363: f(x)= 16373.774814501803
# differential_evolution step 364: f(x)= 16373.774814501803
# differential_evolution step 365: f(x)= 16373.774814501803
# differential_evolution step 366: f(x)= 16373.774814501803
# differential_evolution step 367: f(x)= 16373.774814501803
# differential_evolution step 368: f(x)= 16373.774814501803
# differential_evolution step 369: f(x)= 16373.774814501803
# differential_evolution step 370: f(x)= 16373.774814501803
# differential_evolution step 371: f(x)= 16373.774814501803
# differential_evolution step 372: f(x)= 16373.774814501803
# differential_evolution step 373: f(x)= 16373.538777563917
# differential_evolution step 374: f(x)= 16373.538777563917
# differential_evolution step 375: f(x)= 16371.66203416199
# differential_evolution step 376: f(x)= 16371.66203416199
# differential_evolution step 377: f(x)= 16371.66203416199
# differential_evolution step 378: f(x)= 16371.66203416199
# differential_evolution step 379: f(x)= 16368.7687614808
# differential_evolution step 380: f(x)= 16368.34705553029
# differential_evolution step 381: f(x)= 16367.95424153839
# differential_evolution step 382: f(x)= 16367.95424153839
# differential_evolution step 383: f(x)= 16366.26173911096
# differential_evolution step 384: f(x)= 16366.26173911096
# differential_evolution step 385: f(x)= 16366.26173911096
# differential_evolution step 386: f(x)= 16366.26173911096
# differential_evolution step 387: f(x)= 16366.26173911096
# differential_evolution step 388: f(x)= 16366.26173911096
# differential_evolution step 389: f(x)= 16365.894554182338
# differential_evolution step 390: f(x)= 16365.894554182338
# differential_evolution step 391: f(x)= 16365.894554182338
# differential_evolution step 392: f(x)= 16365.894554182338
# differential_evolution step 393: f(x)= 16365.894554182338
# differential_evolution step 394: f(x)= 16365.894554182338
# differential_evolution step 395: f(x)= 16365.894554182338
# differential_evolution step 396: f(x)= 16365.10340788795
# differential_evolution step 397: f(x)= 16364.698171540773
# differential_evolution step 398: f(x)= 16364.698171540773
# differential_evolution step 399: f(x)= 16364.698171540773
# differential_evolution step 400: f(x)= 16363.622378343658
# differential_evolution step 401: f(x)= 16363.622378343658
# differential_evolution step 402: f(x)= 16363.622378343658
# differential_evolution step 403: f(x)= 16363.622378343658
# differential_evolution step 404: f(x)= 16363.622378343658
# differential_evolution step 405: f(x)= 16363.519607361679
# differential_evolution step 406: f(x)= 16361.906388957472
# differential_evolution step 407: f(x)= 16361.906388957472
# differential_evolution step 408: f(x)= 16361.906388957472
# differential_evolution step 409: f(x)= 16361.906388957472
# differential_evolution step 410: f(x)= 16361.906388957472
# differential_evolution step 411: f(x)= 16360.798813100486
# differential_evolution step 412: f(x)= 16360.798813100486
# differential_evolution step 413: f(x)= 16360.798813100486
# differential_evolution step 414: f(x)= 16360.798813100486
# differential_evolution step 415: f(x)= 16360.798813100486
# differential_evolution step 416: f(x)= 16360.798813100486
# differential_evolution step 417: f(x)= 16360.798813100486
# differential_evolution step 418: f(x)= 16360.262146413814
# differential_evolution step 419: f(x)= 16360.262146413814
# differential_evolution step 420: f(x)= 16360.262146413814
# differential_evolution step 421: f(x)= 16357.815940126813
# differential_evolution step 422: f(x)= 16357.815940126813
# differential_evolution step 423: f(x)= 16357.815940126813
# differential_evolution step 424: f(x)= 16357.815940126813
# differential_evolution step 425: f(x)= 16357.815940126813
# differential_evolution step 426: f(x)= 16357.815940126813
# differential_evolution step 427: f(x)= 16357.815940126813
# differential_evolution step 428: f(x)= 16357.815940126813
# differential_evolution step 429: f(x)= 16357.815940126813
# differential_evolution step 430: f(x)= 16357.815940126813
# differential_evolution step 431: f(x)= 16357.815940126813
# differential_evolution step 432: f(x)= 16357.815940126813
# differential_evolution step 433: f(x)= 16357.815940126813
# differential_evolution step 434: f(x)= 16357.474695207049
# differential_evolution step 435: f(x)= 16357.474695207049
# differential_evolution step 436: f(x)= 16357.474695207049
# differential_evolution step 437: f(x)= 16357.474695207049
# differential_evolution step 438: f(x)= 16357.474695207049
# differential_evolution step 439: f(x)= 16357.398087478607
# differential_evolution step 440: f(x)= 16357.398087478607
# differential_evolution step 441: f(x)= 16355.74408546263
# differential_evolution step 442: f(x)= 16355.74408546263
# differential_evolution step 443: f(x)= 16355.74408546263
# differential_evolution step 444: f(x)= 16355.74408546263
# differential_evolution step 445: f(x)= 16355.74408546263
# differential_evolution step 446: f(x)= 16355.74408546263
# differential_evolution step 447: f(x)= 16355.74408546263
# differential_evolution step 448: f(x)= 16355.74408546263
# differential_evolution step 449: f(x)= 16355.74408546263
# differential_evolution step 450: f(x)= 16355.74408546263
# differential_evolution step 451: f(x)= 16355.74408546263
# differential_evolution step 452: f(x)= 16355.74408546263
# differential_evolution step 453: f(x)= 16355.74408546263
# differential_evolution step 454: f(x)= 16355.74408546263
# differential_evolution step 455: f(x)= 16355.74408546263
# differential_evolution step 456: f(x)= 16355.74408546263
# differential_evolution step 457: f(x)= 16355.74408546263
# differential_evolution step 458: f(x)= 16355.74408546263
# differential_evolution step 459: f(x)= 16355.74408546263
# differential_evolution step 460: f(x)= 16355.74408546263
# differential_evolution step 461: f(x)= 16355.74408546263
# differential_evolution step 462: f(x)= 16355.74408546263
# differential_evolution step 463: f(x)= 16355.74408546263
# differential_evolution step 464: f(x)= 16355.74408546263
# differential_evolution step 465: f(x)= 16355.74408546263
# differential_evolution step 466: f(x)= 16355.74408546263
# differential_evolution step 467: f(x)= 16355.74408546263
# differential_evolution step 468: f(x)= 16355.74408546263
# differential_evolution step 469: f(x)= 16355.74408546263
# differential_evolution step 470: f(x)= 16355.340681834818
# differential_evolution step 471: f(x)= 16355.340681834818
# differential_evolution step 472: f(x)= 16355.340681834818
# differential_evolution step 473: f(x)= 16355.340681834818
# differential_evolution step 474: f(x)= 16355.340681834818
# differential_evolution step 475: f(x)= 16355.340681834818
# differential_evolution step 476: f(x)= 16355.340681834818
# differential_evolution step 477: f(x)= 16355.340681834818
# differential_evolution step 478: f(x)= 16355.340681834818
# differential_evolution step 479: f(x)= 16355.340681834818
# differential_evolution step 480: f(x)= 16355.340681834818
# differential_evolution step 481: f(x)= 16355.340681834818
# differential_evolution step 482: f(x)= 16355.12967009197
# differential_evolution step 483: f(x)= 16355.12967009197
# differential_evolution step 484: f(x)= 16355.12967009197
# differential_evolution step 485: f(x)= 16355.12967009197
# differential_evolution step 486: f(x)= 16355.12967009197
# differential_evolution step 487: f(x)= 16354.861764924082
# differential_evolution step 488: f(x)= 16354.861764924082
# differential_evolution step 489: f(x)= 16354.861764924082
# differential_evolution step 490: f(x)= 16354.8128700883
# differential_evolution step 491: f(x)= 16354.612173238771
# differential_evolution step 492: f(x)= 16354.089854003123
# differential_evolution step 493: f(x)= 16354.089854003123
# differential_evolution step 494: f(x)= 16354.062628111988
# differential_evolution step 495: f(x)= 16354.062628111988
# differential_evolution step 496: f(x)= 16354.062628111988
# differential_evolution step 497: f(x)= 16354.062628111988
# differential_evolution step 498: f(x)= 16354.062628111988
# differential_evolution step 499: f(x)= 16354.062628111988
# differential_evolution step 500: f(x)= 16353.682498835587
# differential_evolution step 501: f(x)= 16353.682498835587
# differential_evolution step 502: f(x)= 16353.682498835587
# differential_evolution step 503: f(x)= 16353.682498835587
# differential_evolution step 504: f(x)= 16353.682498835587
# differential_evolution step 505: f(x)= 16353.682498835587
# differential_evolution step 506: f(x)= 16353.370702923157
# differential_evolution step 507: f(x)= 16353.370702923157
# differential_evolution step 508: f(x)= 16353.370702923157
# differential_evolution step 509: f(x)= 16353.370702923157
# differential_evolution step 510: f(x)= 16353.370702923157
# differential_evolution step 511: f(x)= 16353.370702923157
# differential_evolution step 512: f(x)= 16353.370702923157
# differential_evolution step 513: f(x)= 16353.370702923157
# differential_evolution step 514: f(x)= 16353.370702923157
# differential_evolution step 515: f(x)= 16353.370702923157
# differential_evolution step 516: f(x)= 16353.370702923157
# differential_evolution step 517: f(x)= 16353.370702923157
# differential_evolution step 518: f(x)= 16353.286873311996
# differential_evolution step 519: f(x)= 16353.286873311996
# differential_evolution step 520: f(x)= 16353.286873311996
# differential_evolution step 521: f(x)= 16353.286873311996
# differential_evolution step 522: f(x)= 16353.286873311996
# differential_evolution step 523: f(x)= 16353.286873311996
# differential_evolution step 524: f(x)= 16353.286873311996
# differential_evolution step 525: f(x)= 16353.286873311996
# differential_evolution step 526: f(x)= 16353.286873311996
# differential_evolution step 527: f(x)= 16353.286873311996
# differential_evolution step 528: f(x)= 16353.286873311996
# differential_evolution step 529: f(x)= 16353.286873311996
# differential_evolution step 530: f(x)= 16353.286873311996
# differential_evolution step 531: f(x)= 16353.114395084072
# differential_evolution step 532: f(x)= 16353.114395084072
# differential_evolution step 533: f(x)= 16353.114395084072
# differential_evolution step 534: f(x)= 16353.114395084072
# differential_evolution step 535: f(x)= 16353.114395084072
# differential_evolution step 536: f(x)= 16353.114395084072
# differential_evolution step 537: f(x)= 16353.114395084072
# differential_evolution step 538: f(x)= 16353.103345459805
# differential_evolution step 539: f(x)= 16353.103345459805
# differential_evolution step 540: f(x)= 16353.103345459805
# differential_evolution step 541: f(x)= 16352.802566084321
# differential_evolution step 542: f(x)= 16352.802566084321
# differential_evolution step 543: f(x)= 16352.802566084321
# differential_evolution step 544: f(x)= 16352.802566084321
# differential_evolution step 545: f(x)= 16352.802566084321
# differential_evolution step 546: f(x)= 16352.802566084321
# differential_evolution step 547: f(x)= 16352.802566084321
# differential_evolution step 548: f(x)= 16352.802566084321
# differential_evolution step 549: f(x)= 16352.802566084321
# differential_evolution step 550: f(x)= 16352.802566084321
# differential_evolution step 551: f(x)= 16352.802566084321
# differential_evolution step 552: f(x)= 16352.802566084321
# differential_evolution step 553: f(x)= 16352.691762506909
# differential_evolution step 554: f(x)= 16352.691762506909
# differential_evolution step 555: f(x)= 16352.691762506909
# differential_evolution step 556: f(x)= 16352.691762506909
# differential_evolution step 557: f(x)= 16352.691762506909
# differential_evolution step 558: f(x)= 16352.691762506909
# differential_evolution step 559: f(x)= 16352.691762506909
# differential_evolution step 560: f(x)= 16352.691762506909
# differential_evolution step 561: f(x)= 16352.636332969008
# differential_evolution step 562: f(x)= 16352.636332969008
# differential_evolution step 563: f(x)= 16352.636332969008
# differential_evolution step 564: f(x)= 16352.591937963818
# differential_evolution step 565: f(x)= 16352.591937963818
# differential_evolution step 566: f(x)= 16352.591937963818
# differential_evolution step 567: f(x)= 16352.591937963818
# differential_evolution step 568: f(x)= 16352.591937963818
# differential_evolution step 569: f(x)= 16352.591937963818
# differential_evolution step 570: f(x)= 16352.591937963818
# differential_evolution step 571: f(x)= 16352.591937963818
# differential_evolution step 572: f(x)= 16352.506292699349
# differential_evolution step 573: f(x)= 16352.468514645794
# differential_evolution step 574: f(x)= 16352.468514645794
# differential_evolution step 575: f(x)= 16352.468514645794
# differential_evolution step 576: f(x)= 16352.468514645794
# differential_evolution step 577: f(x)= 16352.468514645794
# differential_evolution step 578: f(x)= 16352.468514645794
# differential_evolution step 579: f(x)= 16352.468514645794
# differential_evolution step 580: f(x)= 16352.468514645794
# differential_evolution step 581: f(x)= 16352.468514645794
# differential_evolution step 582: f(x)= 16352.468514645794
# differential_evolution step 583: f(x)= 16352.468514645794
# differential_evolution step 584: f(x)= 16352.468514645794
# differential_evolution step 585: f(x)= 16352.468514645794
# differential_evolution step 586: f(x)= 16352.446072226698
# differential_evolution step 587: f(x)= 16352.444572373597
# differential_evolution step 588: f(x)= 16352.444572373597
# differential_evolution step 589: f(x)= 16352.444572373597
# differential_evolution step 590: f(x)= 16352.444572373597
# differential_evolution step 591: f(x)= 16352.444572373597
# differential_evolution step 592: f(x)= 16352.430776410172
# differential_evolution step 593: f(x)= 16352.430776410172
# differential_evolution step 594: f(x)= 16352.430776410172
# differential_evolution step 595: f(x)= 16352.384757867412
# differential_evolution step 596: f(x)= 16352.384757867412
# differential_evolution step 597: f(x)= 16352.384757867412
# differential_evolution step 598: f(x)= 16352.36150548476
# differential_evolution step 599: f(x)= 16352.36150548476
# differential_evolution step 600: f(x)= 16352.36150548476
# differential_evolution step 601: f(x)= 16352.36150548476
# differential_evolution step 602: f(x)= 16352.36150548476
# differential_evolution step 603: f(x)= 16352.36150548476
# differential_evolution step 604: f(x)= 16352.36150548476
# differential_evolution step 605: f(x)= 16352.35115927748
# differential_evolution step 606: f(x)= 16352.34705156356
# differential_evolution step 607: f(x)= 16352.34705156356
# differential_evolution step 608: f(x)= 16352.33943652027
# differential_evolution step 609: f(x)= 16352.33943652027
# differential_evolution step 610: f(x)= 16352.305067136347
# differential_evolution step 611: f(x)= 16352.305067136347
# differential_evolution step 612: f(x)= 16352.305067136347
# differential_evolution step 613: f(x)= 16352.305067136347
# differential_evolution step 614: f(x)= 16352.305067136347
# differential_evolution step 615: f(x)= 16352.305067136347
# differential_evolution step 616: f(x)= 16352.305067136347
# differential_evolution step 617: f(x)= 16352.305067136347
# differential_evolution step 618: f(x)= 16352.305067136347
# differential_evolution step 619: f(x)= 16352.305067136347
# differential_evolution step 620: f(x)= 16352.305067136347
# differential_evolution step 621: f(x)= 16352.292321501141
# differential_evolution step 622: f(x)= 16352.282947819216
# differential_evolution step 623: f(x)= 16352.282947819216
# differential_evolution step 624: f(x)= 16352.249770975006
# differential_evolution step 625: f(x)= 16352.249770975006
# differential_evolution step 626: f(x)= 16352.249770975006
# differential_evolution step 627: f(x)= 16352.249770975006
# differential_evolution step 628: f(x)= 16352.249770975006
# differential_evolution step 629: f(x)= 16352.249770975006
# differential_evolution step 630: f(x)= 16352.249770975006
# differential_evolution step 631: f(x)= 16352.249770975006
# differential_evolution step 632: f(x)= 16352.249770975006
# differential_evolution step 633: f(x)= 16352.249770975006
# differential_evolution step 634: f(x)= 16352.249770975006
# differential_evolution step 635: f(x)= 16352.249770975006
# differential_evolution step 636: f(x)= 16352.249770975006
# differential_evolution step 637: f(x)= 16352.249770975006
# differential_evolution step 638: f(x)= 16352.249770975006
# differential_evolution step 639: f(x)= 16352.249770975006
# differential_evolution step 640: f(x)= 16352.249770975006
# differential_evolution step 641: f(x)= 16352.249770975006
# differential_evolution step 642: f(x)= 16352.231393168779
# differential_evolution step 643: f(x)= 16352.231393168779
# differential_evolution step 644: f(x)= 16352.231393168779
# differential_evolution step 645: f(x)= 16352.22893447888
# differential_evolution step 646: f(x)= 16352.22893447888
# differential_evolution step 647: f(x)= 16352.22893447888
# differential_evolution step 648: f(x)= 16352.225682303562
# differential_evolution step 649: f(x)= 16352.225682303562
# differential_evolution step 650: f(x)= 16352.225682303562
# differential_evolution step 651: f(x)= 16352.225682303562
# differential_evolution step 652: f(x)= 16352.225682303562
# differential_evolution step 653: f(x)= 16352.210854644758
# differential_evolution step 654: f(x)= 16352.210854644758
# differential_evolution step 655: f(x)= 16352.210854644758
# differential_evolution step 656: f(x)= 16352.210854644758
# differential_evolution step 657: f(x)= 16352.210854644758
# differential_evolution step 658: f(x)= 16352.210854644758
# differential_evolution step 659: f(x)= 16352.210854644758
# differential_evolution step 660: f(x)= 16352.210854644758
# differential_evolution step 661: f(x)= 16352.210854644758
# differential_evolution step 662: f(x)= 16352.210854644758
# differential_evolution step 663: f(x)= 16352.210854644758
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.5000, r_e=50.0000, n=3.8945, x_0=38.5294
# Sérsic 2: I_e=1.5000, r_e=1.0000, n=4.0000, x_0=48.4726
# Sérsic 3: I_e=1.1197, r_e=19.9998, n=3.3030, x_0=80.8785
# Chi quadro minimo: 16352.210854644758
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 1450)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 1450)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_1, r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')

# %%
params_curve_continuum_1, covariance_continuum_1 = curve_fit(model_convolved, x_axes, radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1)

chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1,
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Sérsic 1: I_e=0.7233, r_e=59.5284, n=4.7139, x_0=38.3919
# Sérsic 2: I_e=1.1041, r_e=38.1383, n=3.0601, x_0=48.4726
# Sérsic 3: I_e=0.3762, r_e=35.7897, n=4.2555, x_0=80.8785
# [2.09914920e+00 1.33345330e+02 2.22743126e+00 5.74781318e-02
#  5.94462681e+00 1.60357151e+02 4.46121002e+00 4.81978703e-03
#  4.62999195e+00 2.94548449e+02 1.26750546e+01 4.73267602e-04]
# 891.4065101937177

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 88901.6406574064
# differential_evolution step 2: f(x)= 88901.6406574064
# differential_evolution step 3: f(x)= 81771.7447632589
# differential_evolution step 4: f(x)= 81771.7447632589
# differential_evolution step 5: f(x)= 81771.7447632589
# differential_evolution step 6: f(x)= 79844.25109004199
# differential_evolution step 7: f(x)= 79844.25109004199
# differential_evolution step 8: f(x)= 79844.25109004199
# differential_evolution step 9: f(x)= 77359.65251476236
# differential_evolution step 10: f(x)= 75935.67094510411
# differential_evolution step 11: f(x)= 75935.67094510411
# differential_evolution step 12: f(x)= 75367.69080318762
# differential_evolution step 13: f(x)= 75367.69080318762
# differential_evolution step 14: f(x)= 71005.26961348492
# differential_evolution step 15: f(x)= 71005.26961348492
# differential_evolution step 16: f(x)= 71005.26961348492
# differential_evolution step 17: f(x)= 71005.26961348492
# differential_evolution step 18: f(x)= 71005.26961348492
# differential_evolution step 19: f(x)= 71005.26961348492
# differential_evolution step 20: f(x)= 71005.26961348492
# differential_evolution step 21: f(x)= 70359.8982282502
# differential_evolution step 22: f(x)= 70359.8982282502
# differential_evolution step 23: f(x)= 70359.8982282502
# differential_evolution step 24: f(x)= 70359.8982282502
# differential_evolution step 25: f(x)= 67825.35149309435
# differential_evolution step 26: f(x)= 67825.35149309435
# differential_evolution step 27: f(x)= 67825.35149309435
# differential_evolution step 28: f(x)= 67825.35149309435
# differential_evolution step 29: f(x)= 67825.35149309435
# differential_evolution step 30: f(x)= 66983.86138797954
# differential_evolution step 31: f(x)= 66983.86138797954
# differential_evolution step 32: f(x)= 66983.86138797954
# differential_evolution step 33: f(x)= 66163.99658656343
# differential_evolution step 34: f(x)= 66163.99658656343
# differential_evolution step 35: f(x)= 66163.99658656343
# differential_evolution step 36: f(x)= 64822.19720509898
# differential_evolution step 37: f(x)= 64822.19720509898
# differential_evolution step 38: f(x)= 64822.19720509898
# differential_evolution step 39: f(x)= 64822.19720509898
# differential_evolution step 40: f(x)= 63691.39875169843
# differential_evolution step 41: f(x)= 63691.39875169843
# differential_evolution step 42: f(x)= 63691.39875169843
# differential_evolution step 43: f(x)= 63691.39875169843
# differential_evolution step 44: f(x)= 63691.39875169843
# differential_evolution step 45: f(x)= 63691.39875169843
# differential_evolution step 46: f(x)= 63691.39875169843
# differential_evolution step 47: f(x)= 63691.39875169843
# differential_evolution step 48: f(x)= 63691.39875169843
# differential_evolution step 49: f(x)= 63691.39875169843
# differential_evolution step 50: f(x)= 63691.39875169843
# differential_evolution step 51: f(x)= 63691.39875169843
# differential_evolution step 52: f(x)= 63691.39875169843
# differential_evolution step 53: f(x)= 63691.39875169843
# differential_evolution step 54: f(x)= 63691.39875169843
# differential_evolution step 55: f(x)= 63481.24208191928
# differential_evolution step 56: f(x)= 63481.24208191928
# differential_evolution step 57: f(x)= 63481.24208191928
# differential_evolution step 58: f(x)= 63481.24208191928
# differential_evolution step 59: f(x)= 63481.24208191928
# differential_evolution step 60: f(x)= 62573.11384444897
# differential_evolution step 61: f(x)= 62573.11384444897
# differential_evolution step 62: f(x)= 62573.11384444897
# differential_evolution step 63: f(x)= 62573.11384444897
# differential_evolution step 64: f(x)= 62573.11384444897
# differential_evolution step 65: f(x)= 62573.11384444897
# differential_evolution step 66: f(x)= 62573.11384444897
# differential_evolution step 67: f(x)= 62573.11384444897
# differential_evolution step 68: f(x)= 62573.11384444897
# differential_evolution step 69: f(x)= 62573.11384444897
# differential_evolution step 70: f(x)= 62573.11384444897
# differential_evolution step 71: f(x)= 62245.35979801238
# differential_evolution step 72: f(x)= 61889.07977722269
# differential_evolution step 73: f(x)= 61889.07977722269
# differential_evolution step 74: f(x)= 61889.07977722269
# differential_evolution step 75: f(x)= 61889.07977722269
# differential_evolution step 76: f(x)= 61889.07977722269
# differential_evolution step 77: f(x)= 61889.07977722269
# differential_evolution step 78: f(x)= 61543.14499846139
# differential_evolution step 79: f(x)= 61322.516467251386
# differential_evolution step 80: f(x)= 61322.516467251386
# differential_evolution step 81: f(x)= 61322.516467251386
# differential_evolution step 82: f(x)= 61322.516467251386
# differential_evolution step 83: f(x)= 61322.516467251386
# differential_evolution step 84: f(x)= 61322.516467251386
# differential_evolution step 85: f(x)= 61322.516467251386
# differential_evolution step 86: f(x)= 61176.129706106294
# differential_evolution step 87: f(x)= 61176.129706106294
# differential_evolution step 88: f(x)= 61176.129706106294
# differential_evolution step 89: f(x)= 61176.129706106294
# differential_evolution step 90: f(x)= 61176.129706106294
# differential_evolution step 91: f(x)= 61176.129706106294
# differential_evolution step 92: f(x)= 61176.129706106294
# differential_evolution step 93: f(x)= 61176.129706106294
# differential_evolution step 94: f(x)= 61176.129706106294
# differential_evolution step 95: f(x)= 61176.129706106294
# differential_evolution step 96: f(x)= 61176.129706106294
# differential_evolution step 97: f(x)= 61116.24617376646
# differential_evolution step 98: f(x)= 61116.24617376646
# differential_evolution step 99: f(x)= 58914.69460528027
# differential_evolution step 100: f(x)= 58914.69460528027
# differential_evolution step 101: f(x)= 58914.69460528027
# differential_evolution step 102: f(x)= 58914.69460528027
# differential_evolution step 103: f(x)= 58914.69460528027
# differential_evolution step 104: f(x)= 58914.69460528027
# differential_evolution step 105: f(x)= 58914.69460528027
# differential_evolution step 106: f(x)= 58914.69460528027
# differential_evolution step 107: f(x)= 58914.69460528027
# differential_evolution step 108: f(x)= 58914.69460528027
# differential_evolution step 109: f(x)= 58914.69460528027
# differential_evolution step 110: f(x)= 58914.69460528027
# differential_evolution step 111: f(x)= 58914.69460528027
# differential_evolution step 112: f(x)= 58914.69460528027
# differential_evolution step 113: f(x)= 58914.69460528027
# differential_evolution step 114: f(x)= 58914.69460528027
# differential_evolution step 115: f(x)= 58388.01603945003
# differential_evolution step 116: f(x)= 58388.01603945003
# differential_evolution step 117: f(x)= 57978.99760998677
# differential_evolution step 118: f(x)= 57978.99760998677
# differential_evolution step 119: f(x)= 57978.99760998677
# differential_evolution step 120: f(x)= 57978.99760998677
# differential_evolution step 121: f(x)= 55669.47987849696
# differential_evolution step 122: f(x)= 55669.47987849696
# differential_evolution step 123: f(x)= 55669.47987849696
# differential_evolution step 124: f(x)= 55669.47987849696
# differential_evolution step 125: f(x)= 55669.47987849696
# differential_evolution step 126: f(x)= 55669.47987849696
# differential_evolution step 127: f(x)= 55669.47987849696
# differential_evolution step 128: f(x)= 55669.47987849696
# differential_evolution step 129: f(x)= 55669.47987849696
# differential_evolution step 130: f(x)= 55669.47987849696
# differential_evolution step 131: f(x)= 55669.47987849696
# differential_evolution step 132: f(x)= 55669.47987849696
# differential_evolution step 133: f(x)= 55669.47987849696
# differential_evolution step 134: f(x)= 55669.47987849696
# differential_evolution step 135: f(x)= 55669.47987849696
# differential_evolution step 136: f(x)= 55669.47987849696
# differential_evolution step 137: f(x)= 55669.47987849696
# differential_evolution step 138: f(x)= 55669.47987849696
# differential_evolution step 139: f(x)= 55669.47987849696
# differential_evolution step 140: f(x)= 55669.47987849696
# differential_evolution step 141: f(x)= 55669.47987849696
# differential_evolution step 142: f(x)= 55669.47987849696
# differential_evolution step 143: f(x)= 55669.47987849696
# differential_evolution step 144: f(x)= 55669.47987849696
# differential_evolution step 145: f(x)= 55669.47987849696
# differential_evolution step 146: f(x)= 55596.74990716804
# differential_evolution step 147: f(x)= 55596.74990716804
# differential_evolution step 148: f(x)= 55596.74990716804
# differential_evolution step 149: f(x)= 55596.74990716804
# differential_evolution step 150: f(x)= 55513.85375451885
# differential_evolution step 151: f(x)= 55513.85375451885
# differential_evolution step 152: f(x)= 55513.85375451885
# differential_evolution step 153: f(x)= 55513.85375451885
# differential_evolution step 154: f(x)= 55513.85375451885
# differential_evolution step 155: f(x)= 55513.85375451885
# differential_evolution step 156: f(x)= 55513.85375451885
# differential_evolution step 157: f(x)= 55513.85375451885
# differential_evolution step 158: f(x)= 55513.85375451885
# differential_evolution step 159: f(x)= 55513.85375451885
# differential_evolution step 160: f(x)= 55513.85375451885
# differential_evolution step 161: f(x)= 55513.85375451885
# differential_evolution step 162: f(x)= 55513.85375451885
# differential_evolution step 163: f(x)= 55513.85375451885
# differential_evolution step 164: f(x)= 55513.85375451885
# differential_evolution step 165: f(x)= 55513.85375451885
# differential_evolution step 166: f(x)= 55228.61576499621
# differential_evolution step 167: f(x)= 55228.61576499621
# differential_evolution step 168: f(x)= 55228.61576499621
# differential_evolution step 169: f(x)= 55228.61576499621
# differential_evolution step 170: f(x)= 55228.61576499621
# differential_evolution step 171: f(x)= 55228.61576499621
# differential_evolution step 172: f(x)= 55228.61576499621
# differential_evolution step 173: f(x)= 55228.61576499621
# differential_evolution step 174: f(x)= 55170.23462286419
# differential_evolution step 175: f(x)= 55170.23462286419
# differential_evolution step 176: f(x)= 55170.23462286419
# differential_evolution step 177: f(x)= 55170.23462286419
# differential_evolution step 178: f(x)= 55170.23462286419
# differential_evolution step 179: f(x)= 54256.44334731862
# differential_evolution step 180: f(x)= 54256.44334731862
# differential_evolution step 181: f(x)= 54256.44334731862
# differential_evolution step 182: f(x)= 54256.44334731862
# differential_evolution step 183: f(x)= 54256.44334731862
# differential_evolution step 184: f(x)= 54123.88568510014
# differential_evolution step 185: f(x)= 54123.88568510014
# differential_evolution step 186: f(x)= 53744.99449647367
# differential_evolution step 187: f(x)= 53744.99449647367
# differential_evolution step 188: f(x)= 53744.99449647367
# differential_evolution step 189: f(x)= 53744.99449647367
# differential_evolution step 190: f(x)= 53744.99449647367
# differential_evolution step 191: f(x)= 53744.99449647367
# differential_evolution step 192: f(x)= 53325.78508159043
# differential_evolution step 193: f(x)= 53325.78508159043
# differential_evolution step 194: f(x)= 53325.78508159043
# differential_evolution step 195: f(x)= 53325.78508159043
# differential_evolution step 196: f(x)= 53325.78508159043
# differential_evolution step 197: f(x)= 53325.78508159043
# differential_evolution step 198: f(x)= 53325.78508159043
# differential_evolution step 199: f(x)= 53325.78508159043
# differential_evolution step 200: f(x)= 53325.78508159043
# differential_evolution step 201: f(x)= 53325.78508159043
# differential_evolution step 202: f(x)= 53325.78508159043
# differential_evolution step 203: f(x)= 53325.78508159043
# differential_evolution step 204: f(x)= 52674.4267181506
# differential_evolution step 205: f(x)= 52674.4267181506
# differential_evolution step 206: f(x)= 52674.4267181506
# differential_evolution step 207: f(x)= 52674.4267181506
# differential_evolution step 208: f(x)= 52674.4267181506
# differential_evolution step 209: f(x)= 52674.4267181506
# differential_evolution step 210: f(x)= 52674.4267181506
# differential_evolution step 211: f(x)= 52674.4267181506
# differential_evolution step 212: f(x)= 52674.4267181506
# differential_evolution step 213: f(x)= 52674.4267181506
# differential_evolution step 214: f(x)= 52674.4267181506
# differential_evolution step 215: f(x)= 52674.4267181506
# differential_evolution step 216: f(x)= 52674.4267181506
# differential_evolution step 217: f(x)= 52674.4267181506
# differential_evolution step 218: f(x)= 52280.526189311735
# differential_evolution step 219: f(x)= 52280.526189311735
# differential_evolution step 220: f(x)= 52280.526189311735
# differential_evolution step 221: f(x)= 52280.526189311735
# differential_evolution step 222: f(x)= 52280.526189311735
# differential_evolution step 223: f(x)= 52280.526189311735
# differential_evolution step 224: f(x)= 52280.526189311735
# differential_evolution step 225: f(x)= 52093.46055164073
# differential_evolution step 226: f(x)= 51946.70564936666
# differential_evolution step 227: f(x)= 51946.70564936666
# differential_evolution step 228: f(x)= 51946.70564936666
# differential_evolution step 229: f(x)= 51946.70564936666
# differential_evolution step 230: f(x)= 51946.70564936666
# differential_evolution step 231: f(x)= 51946.70564936666
# differential_evolution step 232: f(x)= 51946.70564936666
# differential_evolution step 233: f(x)= 51934.812706613666
# differential_evolution step 234: f(x)= 51934.812706613666
# differential_evolution step 235: f(x)= 51934.812706613666
# differential_evolution step 236: f(x)= 51898.2944216358
# differential_evolution step 237: f(x)= 51501.16416548354
# differential_evolution step 238: f(x)= 51501.16416548354
# differential_evolution step 239: f(x)= 51501.16416548354
# differential_evolution step 240: f(x)= 51501.16416548354
# differential_evolution step 241: f(x)= 51501.16416548354
# differential_evolution step 242: f(x)= 51501.16416548354
# differential_evolution step 243: f(x)= 51501.16416548354
# differential_evolution step 244: f(x)= 51501.16416548354
# differential_evolution step 245: f(x)= 51501.16416548354
# differential_evolution step 246: f(x)= 51501.16416548354
# differential_evolution step 247: f(x)= 51501.16416548354
# differential_evolution step 248: f(x)= 51501.16416548354
# differential_evolution step 249: f(x)= 51229.44104995562
# differential_evolution step 250: f(x)= 51198.759482208
# differential_evolution step 251: f(x)= 51198.759482208
# differential_evolution step 252: f(x)= 51198.759482208
# differential_evolution step 253: f(x)= 51198.759482208
# differential_evolution step 254: f(x)= 51026.563353838195
# differential_evolution step 255: f(x)= 51026.563353838195
# differential_evolution step 256: f(x)= 51026.563353838195
# differential_evolution step 257: f(x)= 51026.563353838195
# differential_evolution step 258: f(x)= 51026.563353838195
# differential_evolution step 259: f(x)= 51026.563353838195
# differential_evolution step 260: f(x)= 51026.563353838195
# differential_evolution step 261: f(x)= 51026.563353838195
# differential_evolution step 262: f(x)= 51026.563353838195
# differential_evolution step 263: f(x)= 51026.563353838195
# differential_evolution step 264: f(x)= 50943.07634492153
# differential_evolution step 265: f(x)= 50943.07634492153
# differential_evolution step 266: f(x)= 50853.563692839714
# differential_evolution step 267: f(x)= 50853.563692839714
# differential_evolution step 268: f(x)= 50853.563692839714
# differential_evolution step 269: f(x)= 50853.563692839714
# differential_evolution step 270: f(x)= 50853.563692839714
# differential_evolution step 271: f(x)= 50853.563692839714
# differential_evolution step 272: f(x)= 50853.563692839714
# differential_evolution step 273: f(x)= 50701.939787110765
# differential_evolution step 274: f(x)= 50701.939787110765
# differential_evolution step 275: f(x)= 50701.939787110765
# differential_evolution step 276: f(x)= 50701.939787110765
# differential_evolution step 277: f(x)= 50701.939787110765
# differential_evolution step 278: f(x)= 50701.939787110765
# differential_evolution step 279: f(x)= 50701.939787110765
# differential_evolution step 280: f(x)= 50701.939787110765
# differential_evolution step 281: f(x)= 50701.939787110765
# differential_evolution step 282: f(x)= 50693.05506246834
# differential_evolution step 283: f(x)= 50693.05506246834
# differential_evolution step 284: f(x)= 50693.05506246834
# differential_evolution step 285: f(x)= 50693.05506246834
# differential_evolution step 286: f(x)= 50693.05506246834
# differential_evolution step 287: f(x)= 50693.05506246834
# differential_evolution step 288: f(x)= 50693.05506246834
# differential_evolution step 289: f(x)= 50693.05506246834
# differential_evolution step 290: f(x)= 50678.349644110785
# differential_evolution step 291: f(x)= 50678.349644110785
# differential_evolution step 292: f(x)= 50645.461977749335
# differential_evolution step 293: f(x)= 50623.56330373814
# differential_evolution step 294: f(x)= 50623.56330373814
# differential_evolution step 295: f(x)= 50623.56330373814
# differential_evolution step 296: f(x)= 50623.56330373814
# differential_evolution step 297: f(x)= 50585.136715724955
# differential_evolution step 298: f(x)= 50585.136715724955
# differential_evolution step 299: f(x)= 50585.136715724955
# differential_evolution step 300: f(x)= 50585.136715724955
# differential_evolution step 301: f(x)= 50585.136715724955
# differential_evolution step 302: f(x)= 50584.56321003261
# differential_evolution step 303: f(x)= 50584.56321003261
# differential_evolution step 304: f(x)= 50580.92527868017
# differential_evolution step 305: f(x)= 50580.92527868017
# differential_evolution step 306: f(x)= 50580.92527868017
# differential_evolution step 307: f(x)= 50566.37097986099
# differential_evolution step 308: f(x)= 50566.37097986099
# differential_evolution step 309: f(x)= 50566.37097986099
# differential_evolution step 310: f(x)= 50566.37097986099
# differential_evolution step 311: f(x)= 50566.37097986099
# differential_evolution step 312: f(x)= 50566.37097986099
# differential_evolution step 313: f(x)= 50535.52696870291
# differential_evolution step 314: f(x)= 50535.52696870291
# differential_evolution step 315: f(x)= 50535.52696870291
# differential_evolution step 316: f(x)= 50535.52696870291
# differential_evolution step 317: f(x)= 50535.52696870291
# differential_evolution step 318: f(x)= 50535.52696870291
# differential_evolution step 319: f(x)= 50535.52696870291
# differential_evolution step 320: f(x)= 50535.52696870291
# differential_evolution step 321: f(x)= 50531.32323381084
# differential_evolution step 322: f(x)= 50531.32323381084
# differential_evolution step 323: f(x)= 50531.32323381084
# differential_evolution step 324: f(x)= 50522.827867065665
# differential_evolution step 325: f(x)= 50522.827867065665
# differential_evolution step 326: f(x)= 50522.827867065665
# differential_evolution step 327: f(x)= 50510.091616422425
# differential_evolution step 328: f(x)= 50510.091616422425
# differential_evolution step 329: f(x)= 50510.091616422425
# differential_evolution step 330: f(x)= 50497.78920505269
# differential_evolution step 331: f(x)= 50497.78920505269
# differential_evolution step 332: f(x)= 50497.78920505269
# differential_evolution step 333: f(x)= 50497.78920505269
# differential_evolution step 334: f(x)= 50497.78920505269
# differential_evolution step 335: f(x)= 50497.78920505269
# differential_evolution step 336: f(x)= 50497.78920505269
# differential_evolution step 337: f(x)= 50497.78920505269
# differential_evolution step 338: f(x)= 50497.78920505269
# differential_evolution step 339: f(x)= 50497.78920505269
# differential_evolution step 340: f(x)= 50497.78920505269
# differential_evolution step 341: f(x)= 50483.89202208857
# differential_evolution step 342: f(x)= 50483.89202208857
# differential_evolution step 343: f(x)= 50483.89202208857
# differential_evolution step 344: f(x)= 50483.89202208857
# differential_evolution step 345: f(x)= 50483.89202208857
# differential_evolution step 346: f(x)= 50483.89202208857
# differential_evolution step 347: f(x)= 50477.14828126559
# differential_evolution step 348: f(x)= 50476.1798416133
# differential_evolution step 349: f(x)= 50475.84450733255
# differential_evolution step 350: f(x)= 50475.84450733255
# differential_evolution step 351: f(x)= 50475.84450733255
# differential_evolution step 352: f(x)= 50469.60093561266
# differential_evolution step 353: f(x)= 50466.66909979892
# differential_evolution step 354: f(x)= 50466.66909979892
# differential_evolution step 355: f(x)= 50466.66909979892
# differential_evolution step 356: f(x)= 50461.18683552947
# differential_evolution step 357: f(x)= 50461.18683552947
# differential_evolution step 358: f(x)= 50460.102694175715
# differential_evolution step 359: f(x)= 50456.45905594293
# differential_evolution step 360: f(x)= 50456.45905594293
# differential_evolution step 361: f(x)= 50456.45905594293
# differential_evolution step 362: f(x)= 50455.72801713263
# differential_evolution step 363: f(x)= 50455.72801713263
# differential_evolution step 364: f(x)= 50455.72801713263
# differential_evolution step 365: f(x)= 50455.72801713263
# differential_evolution step 366: f(x)= 50452.56199367658
# differential_evolution step 367: f(x)= 50452.56199367658
# differential_evolution step 368: f(x)= 50452.56199367658
# differential_evolution step 369: f(x)= 50450.747895566594
# differential_evolution step 370: f(x)= 50450.747895566594
# differential_evolution step 371: f(x)= 50450.747895566594
# differential_evolution step 372: f(x)= 50450.747895566594
# differential_evolution step 373: f(x)= 50450.747895566594
# differential_evolution step 374: f(x)= 50450.747895566594
# differential_evolution step 375: f(x)= 50450.747895566594
# differential_evolution step 376: f(x)= 50450.747895566594
# differential_evolution step 377: f(x)= 50450.06613819432
# differential_evolution step 378: f(x)= 50450.06613819432
# differential_evolution step 379: f(x)= 50449.900446942156
# differential_evolution step 380: f(x)= 50449.900446942156
# differential_evolution step 381: f(x)= 50449.900446942156
# differential_evolution step 382: f(x)= 50448.51475648995
# differential_evolution step 383: f(x)= 50448.512778306984
# differential_evolution step 384: f(x)= 50448.512778306984
# differential_evolution step 385: f(x)= 50448.512778306984
# differential_evolution step 386: f(x)= 50448.512778306984
# differential_evolution step 387: f(x)= 50448.512778306984
# differential_evolution step 388: f(x)= 50445.383869608035
# differential_evolution step 389: f(x)= 50445.383869608035
# differential_evolution step 390: f(x)= 50445.383869608035
# differential_evolution step 391: f(x)= 50445.35647883171
# differential_evolution step 392: f(x)= 50445.35647883171
# differential_evolution step 393: f(x)= 50445.35647883171
# differential_evolution step 394: f(x)= 50445.35647883171
# differential_evolution step 395: f(x)= 50445.35647883171
# differential_evolution step 396: f(x)= 50445.35647883171
# differential_evolution step 397: f(x)= 50445.35647883171
# differential_evolution step 398: f(x)= 50445.35647883171
# differential_evolution step 399: f(x)= 50445.35647883171
# differential_evolution step 400: f(x)= 50445.1786166204
# differential_evolution step 401: f(x)= 50445.1786166204
# differential_evolution step 402: f(x)= 50445.1786166204
# differential_evolution step 403: f(x)= 50445.1786166204
# differential_evolution step 404: f(x)= 50445.1786166204
# differential_evolution step 405: f(x)= 50445.1786166204
# differential_evolution step 406: f(x)= 50445.1786166204
# differential_evolution step 407: f(x)= 50445.1786166204
# differential_evolution step 408: f(x)= 50445.1786166204
# differential_evolution step 409: f(x)= 50445.1786166204
# differential_evolution step 410: f(x)= 50445.1786166204
# differential_evolution step 411: f(x)= 50445.1786166204
# differential_evolution step 412: f(x)= 50444.90046162527
# differential_evolution step 413: f(x)= 50444.53270842917
# differential_evolution step 414: f(x)= 50444.53270842917
# differential_evolution step 415: f(x)= 50444.53270842917
# differential_evolution step 416: f(x)= 50443.74725982652
# differential_evolution step 417: f(x)= 50443.74725982652
# differential_evolution step 418: f(x)= 50443.74725982652
# differential_evolution step 419: f(x)= 50443.74725982652
# differential_evolution step 420: f(x)= 50443.72373750563
# differential_evolution step 421: f(x)= 50443.72373750563
# differential_evolution step 422: f(x)= 50443.312706767756
# differential_evolution step 423: f(x)= 50443.312706767756
# differential_evolution step 424: f(x)= 50443.312706767756
# differential_evolution step 425: f(x)= 50443.312706767756
# differential_evolution step 426: f(x)= 50443.312706767756
# differential_evolution step 427: f(x)= 50443.312706767756
# differential_evolution step 428: f(x)= 50443.12273364151
# differential_evolution step 429: f(x)= 50442.15520195354
# differential_evolution step 430: f(x)= 50442.15520195354
# differential_evolution step 431: f(x)= 50442.15520195354
# differential_evolution step 432: f(x)= 50442.15520195354
# differential_evolution step 433: f(x)= 50442.15520195354
# differential_evolution step 434: f(x)= 50442.15520195354
# differential_evolution step 435: f(x)= 50442.15520195354
# differential_evolution step 436: f(x)= 50442.15520195354
# differential_evolution step 437: f(x)= 50442.15520195354
# differential_evolution step 438: f(x)= 50442.15520195354
# differential_evolution step 439: f(x)= 50442.15520195354
# differential_evolution step 440: f(x)= 50442.15520195354
# differential_evolution step 441: f(x)= 50442.15520195354
# differential_evolution step 442: f(x)= 50442.15520195354
# differential_evolution step 443: f(x)= 50442.15520195354
# differential_evolution step 444: f(x)= 50442.15520195354
# differential_evolution step 445: f(x)= 50442.15520195354
# differential_evolution step 446: f(x)= 50442.15520195354
# differential_evolution step 447: f(x)= 50442.15520195354
# differential_evolution step 448: f(x)= 50442.15520195354
# differential_evolution step 449: f(x)= 50442.11822735481
# differential_evolution step 450: f(x)= 50442.11822735481
# differential_evolution step 451: f(x)= 50442.046468888555
# differential_evolution step 452: f(x)= 50441.944657518674
# differential_evolution step 453: f(x)= 50441.944657518674
# differential_evolution step 454: f(x)= 50441.944657518674
# differential_evolution step 455: f(x)= 50441.944657518674
# differential_evolution step 456: f(x)= 50441.9281456828
# differential_evolution step 457: f(x)= 50441.9281456828
# differential_evolution step 458: f(x)= 50441.9281456828
# differential_evolution step 459: f(x)= 50441.9281456828
# differential_evolution step 460: f(x)= 50441.84475999051
# differential_evolution step 461: f(x)= 50441.84475999051
# differential_evolution step 462: f(x)= 50441.84475999051
# differential_evolution step 463: f(x)= 50441.64053346929
# differential_evolution step 464: f(x)= 50441.64053346929
# differential_evolution step 465: f(x)= 50441.64053346929
# differential_evolution step 466: f(x)= 50441.631707444794
# differential_evolution step 467: f(x)= 50441.631707444794
# differential_evolution step 468: f(x)= 50441.33234854066
# differential_evolution step 469: f(x)= 50441.33234854066
# differential_evolution step 470: f(x)= 50441.33234854066
# differential_evolution step 471: f(x)= 50441.33234854066
# differential_evolution step 472: f(x)= 50441.21740772133
# differential_evolution step 473: f(x)= 50441.21740772133
# differential_evolution step 474: f(x)= 50441.21740772133
# differential_evolution step 475: f(x)= 50441.21740772133
# differential_evolution step 476: f(x)= 50441.21740772133
# differential_evolution step 477: f(x)= 50441.21740772133
# differential_evolution step 478: f(x)= 50441.21740772133
# differential_evolution step 479: f(x)= 50441.21740772133
# differential_evolution step 480: f(x)= 50441.21740772133
# differential_evolution step 481: f(x)= 50441.21740772133
# differential_evolution step 482: f(x)= 50441.21740772133
# differential_evolution step 483: f(x)= 50441.21740772133
# differential_evolution step 484: f(x)= 50441.21740772133
# differential_evolution step 485: f(x)= 50441.21740772133
# differential_evolution step 486: f(x)= 50441.21740772133
# differential_evolution step 487: f(x)= 50441.21740772133
# differential_evolution step 488: f(x)= 50441.03215489782
# differential_evolution step 489: f(x)= 50441.03215489782
# differential_evolution step 490: f(x)= 50441.03215489782
# differential_evolution step 491: f(x)= 50440.772886981664
# differential_evolution step 492: f(x)= 50440.772886981664
# differential_evolution step 493: f(x)= 50440.772886981664
# differential_evolution step 494: f(x)= 50440.772886981664
# differential_evolution step 495: f(x)= 50440.772886981664
# differential_evolution step 496: f(x)= 50440.772886981664
# differential_evolution step 497: f(x)= 50440.75120517637
# differential_evolution step 498: f(x)= 50440.75120517637
# differential_evolution step 499: f(x)= 50440.75120517637
# differential_evolution step 500: f(x)= 50440.75120517637
# differential_evolution step 501: f(x)= 50440.75120517637
# differential_evolution step 502: f(x)= 50440.75120517637
# differential_evolution step 503: f(x)= 50440.75120517637
# differential_evolution step 504: f(x)= 50440.75120517637
# differential_evolution step 505: f(x)= 50440.75120517637
# differential_evolution step 506: f(x)= 50440.73436078164
# differential_evolution step 507: f(x)= 50440.68959698104
# differential_evolution step 508: f(x)= 50440.68959698104
# differential_evolution step 509: f(x)= 50440.68959698104
# differential_evolution step 510: f(x)= 50440.68959698104
# differential_evolution step 511: f(x)= 50440.68959698104
# differential_evolution step 512: f(x)= 50440.68959698104
# differential_evolution step 513: f(x)= 50440.657825998685
# differential_evolution step 514: f(x)= 50440.657825998685
# differential_evolution step 515: f(x)= 50440.657825998685
# differential_evolution step 516: f(x)= 50440.657825998685
# differential_evolution step 517: f(x)= 50440.54505459104
# differential_evolution step 518: f(x)= 50440.54505459104
# differential_evolution step 519: f(x)= 50440.54505459104
# differential_evolution step 520: f(x)= 50440.54505459104
# differential_evolution step 521: f(x)= 50440.419020560075
# differential_evolution step 522: f(x)= 50440.419020560075
# differential_evolution step 523: f(x)= 50440.419020560075
# differential_evolution step 524: f(x)= 50440.40286346112
# differential_evolution step 525: f(x)= 50440.40286346112
# differential_evolution step 526: f(x)= 50440.40286346112
# differential_evolution step 527: f(x)= 50440.40286346112
# differential_evolution step 528: f(x)= 50440.40286346112
# differential_evolution step 529: f(x)= 50440.40286346112
# differential_evolution step 530: f(x)= 50440.40286346112
# differential_evolution step 531: f(x)= 50440.40286346112
# differential_evolution step 532: f(x)= 50440.40286346112
# differential_evolution step 533: f(x)= 50440.40286346112
# differential_evolution step 534: f(x)= 50440.40286346112
# differential_evolution step 535: f(x)= 50440.25310774562
# differential_evolution step 536: f(x)= 50440.25310774562
# differential_evolution step 537: f(x)= 50440.25310774562
# differential_evolution step 538: f(x)= 50440.25310774562
# differential_evolution step 539: f(x)= 50440.25310774562
# differential_evolution step 540: f(x)= 50440.25310774562
# differential_evolution step 541: f(x)= 50440.25310774562
# differential_evolution step 542: f(x)= 50440.25310774562
# differential_evolution step 543: f(x)= 50440.25310774562
# differential_evolution step 544: f(x)= 50440.23566523524
# differential_evolution step 545: f(x)= 50440.23566523524
# differential_evolution step 546: f(x)= 50440.23566523524
# differential_evolution step 547: f(x)= 50440.23566523524
# differential_evolution step 548: f(x)= 50440.23566523524
# differential_evolution step 549: f(x)= 50440.23566523524
# differential_evolution step 550: f(x)= 50440.23566523524
# differential_evolution step 551: f(x)= 50440.23566523524
# differential_evolution step 552: f(x)= 50440.23566523524
# differential_evolution step 553: f(x)= 50440.23566523524
# differential_evolution step 554: f(x)= 50440.23566523524
# differential_evolution step 555: f(x)= 50440.23566523524
# differential_evolution step 556: f(x)= 50440.183438044594
# differential_evolution step 557: f(x)= 50440.183438044594
# differential_evolution step 558: f(x)= 50440.183438044594
# differential_evolution step 559: f(x)= 50440.183438044594
# differential_evolution step 560: f(x)= 50440.183438044594
# differential_evolution step 561: f(x)= 50440.183438044594
# differential_evolution step 562: f(x)= 50440.183438044594
# differential_evolution step 563: f(x)= 50440.183438044594
# differential_evolution step 564: f(x)= 50440.183438044594
# differential_evolution step 565: f(x)= 50440.183438044594
# differential_evolution step 566: f(x)= 50440.183438044594
# differential_evolution step 567: f(x)= 50440.183438044594
# differential_evolution step 568: f(x)= 50440.18103931783
# differential_evolution step 569: f(x)= 50440.18103931783
# differential_evolution step 570: f(x)= 50440.18103931783
# differential_evolution step 571: f(x)= 50440.148036296254
# differential_evolution step 572: f(x)= 50440.14230958195
# differential_evolution step 573: f(x)= 50440.14230958195
# differential_evolution step 574: f(x)= 50440.14230958195
# differential_evolution step 575: f(x)= 50440.126468188035
# differential_evolution step 576: f(x)= 50440.126468188035
# differential_evolution step 577: f(x)= 50440.126468188035
# differential_evolution step 578: f(x)= 50440.126468188035
# differential_evolution step 579: f(x)= 50440.11603194566
# differential_evolution step 580: f(x)= 50440.11603194566
# differential_evolution step 581: f(x)= 50440.11603194566
# differential_evolution step 582: f(x)= 50440.11603194566
# differential_evolution step 583: f(x)= 50440.11603194566
# differential_evolution step 584: f(x)= 50440.11603194566
# differential_evolution step 585: f(x)= 50440.11482065804
# differential_evolution step 586: f(x)= 50440.11482065804
# differential_evolution step 587: f(x)= 50440.11482065804
# differential_evolution step 588: f(x)= 50440.11482065804
# differential_evolution step 589: f(x)= 50440.10969381968
# differential_evolution step 590: f(x)= 50440.10969381968
# differential_evolution step 591: f(x)= 50440.09341743538
# differential_evolution step 592: f(x)= 50440.08920656779
# differential_evolution step 593: f(x)= 50440.08920656779
# differential_evolution step 594: f(x)= 50440.08092259139
# differential_evolution step 595: f(x)= 50440.08092259139
# differential_evolution step 596: f(x)= 50440.08092259139
# differential_evolution step 597: f(x)= 50440.08092259139
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.5000, r_e=50.0000, n=3.2881, x_0=38.7802
# Sérsic 2: I_e=1.5000, r_e=1.0000, n=4.0000, x_0=48.2251
# Sérsic 3: I_e=1.5000, r_e=19.9999, n=3.1999, x_0=81.0765
# Chi quadro minimo: 50440.08092259139
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, )
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, )
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
plot_diff(x_axes, best_params, radial_profile_continuum_2, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
params_curve_continuum_2, covariance_continuum_2 = curve_fit(model_convolved, x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2)#, maxfev=15000)
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
    radial_profile_error_continuum_2, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
# Out:
# Sérsic 1: I_e=1.1786, r_e=113.4704, n=2.8890, x_0=38.2248
# Sérsic 2: I_e=2.2460, r_e=21.2039, n=2.8887, x_0=48.2251
# Sérsic 3: I_e=0.9485, r_e=26.2626, n=3.4954, x_0=81.0763
# [1.48406487e+00 1.24789223e+02 8.91346422e-01 1.97977752e-01
#  1.12020292e+01 7.76258666e+01 4.60673557e+00 8.82374575e-03
#  6.08992958e+00 1.15983468e+02 6.44639615e+00 5.61425597e-02]
# 1701.8556147710055

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 33402.93973712872
# differential_evolution step 2: f(x)= 28545.385912633676
# differential_evolution step 3: f(x)= 28545.385912633676
# differential_evolution step 4: f(x)= 26163.616221677672
# differential_evolution step 5: f(x)= 26163.616221677672
# differential_evolution step 6: f(x)= 26163.616221677672
# differential_evolution step 7: f(x)= 25977.452078922073
# differential_evolution step 8: f(x)= 24525.150810669365
# differential_evolution step 9: f(x)= 22875.93679189695
# differential_evolution step 10: f(x)= 21879.329370542502
# differential_evolution step 11: f(x)= 21879.329370542502
# differential_evolution step 12: f(x)= 21879.329370542502
# differential_evolution step 13: f(x)= 21328.095986242046
# differential_evolution step 14: f(x)= 21328.095986242046
# differential_evolution step 15: f(x)= 20651.069696993538
# differential_evolution step 16: f(x)= 20597.517906335182
# differential_evolution step 17: f(x)= 19957.949513696305
# differential_evolution step 18: f(x)= 19957.949513696305
# differential_evolution step 19: f(x)= 19957.949513696305
# differential_evolution step 20: f(x)= 18469.663353930326
# differential_evolution step 21: f(x)= 18469.663353930326
# differential_evolution step 22: f(x)= 18469.663353930326
# differential_evolution step 23: f(x)= 18469.663353930326
# differential_evolution step 24: f(x)= 18469.663353930326
# differential_evolution step 25: f(x)= 18469.663353930326
# differential_evolution step 26: f(x)= 17365.8431725006
# differential_evolution step 27: f(x)= 17365.8431725006
# differential_evolution step 28: f(x)= 16985.25269187686
# differential_evolution step 29: f(x)= 16985.25269187686
# differential_evolution step 30: f(x)= 16985.25269187686
# differential_evolution step 31: f(x)= 16985.25269187686
# differential_evolution step 32: f(x)= 16985.25269187686
# differential_evolution step 33: f(x)= 16985.25269187686
# differential_evolution step 34: f(x)= 16985.25269187686
# differential_evolution step 35: f(x)= 16985.25269187686
# differential_evolution step 36: f(x)= 16078.121269389852
# differential_evolution step 37: f(x)= 16078.121269389852
# differential_evolution step 38: f(x)= 16078.121269389852
# differential_evolution step 39: f(x)= 16078.121269389852
# differential_evolution step 40: f(x)= 16078.121269389852
# differential_evolution step 41: f(x)= 15470.123771802497
# differential_evolution step 42: f(x)= 15470.123771802497
# differential_evolution step 43: f(x)= 15470.123771802497
# differential_evolution step 44: f(x)= 15470.123771802497
# differential_evolution step 45: f(x)= 15470.123771802497
# differential_evolution step 46: f(x)= 15470.123771802497
# differential_evolution step 47: f(x)= 15470.123771802497
# differential_evolution step 48: f(x)= 15470.123771802497
# differential_evolution step 49: f(x)= 15470.123771802497
# differential_evolution step 50: f(x)= 15470.123771802497
# differential_evolution step 51: f(x)= 15470.123771802497
# differential_evolution step 52: f(x)= 15470.123771802497
# differential_evolution step 53: f(x)= 15470.123771802497
# differential_evolution step 54: f(x)= 15470.123771802497
# differential_evolution step 55: f(x)= 15470.123771802497
# differential_evolution step 56: f(x)= 15470.123771802497
# differential_evolution step 57: f(x)= 15470.123771802497
# differential_evolution step 58: f(x)= 14353.072568722726
# differential_evolution step 59: f(x)= 14353.072568722726
# differential_evolution step 60: f(x)= 14353.072568722726
# differential_evolution step 61: f(x)= 14353.072568722726
# differential_evolution step 62: f(x)= 14353.072568722726
# differential_evolution step 63: f(x)= 14353.072568722726
# differential_evolution step 64: f(x)= 14353.072568722726
# differential_evolution step 65: f(x)= 14353.072568722726
# differential_evolution step 66: f(x)= 14353.072568722726
# differential_evolution step 67: f(x)= 14353.072568722726
# differential_evolution step 68: f(x)= 14353.072568722726
# differential_evolution step 69: f(x)= 14353.072568722726
# differential_evolution step 70: f(x)= 14353.072568722726
# differential_evolution step 71: f(x)= 14075.977870743964
# differential_evolution step 72: f(x)= 14075.977870743964
# differential_evolution step 73: f(x)= 13942.091857603906
# differential_evolution step 74: f(x)= 13942.091857603906
# differential_evolution step 75: f(x)= 13942.091857603906
# differential_evolution step 76: f(x)= 13942.091857603906
# differential_evolution step 77: f(x)= 13942.091857603906
# differential_evolution step 78: f(x)= 13850.906291651447
# differential_evolution step 79: f(x)= 13850.906291651447
# differential_evolution step 80: f(x)= 13567.766639327234
# differential_evolution step 81: f(x)= 13567.766639327234
# differential_evolution step 82: f(x)= 13567.766639327234
# differential_evolution step 83: f(x)= 13444.58453289771
# differential_evolution step 84: f(x)= 13444.58453289771
# differential_evolution step 85: f(x)= 13444.58453289771
# differential_evolution step 86: f(x)= 13444.58453289771
# differential_evolution step 87: f(x)= 13444.58453289771
# differential_evolution step 88: f(x)= 13444.58453289771
# differential_evolution step 89: f(x)= 13444.58453289771
# differential_evolution step 90: f(x)= 13444.58453289771
# differential_evolution step 91: f(x)= 13444.58453289771
# differential_evolution step 92: f(x)= 13444.58453289771
# differential_evolution step 93: f(x)= 13444.58453289771
# differential_evolution step 94: f(x)= 13444.58453289771
# differential_evolution step 95: f(x)= 13444.58453289771
# differential_evolution step 96: f(x)= 13444.58453289771
# differential_evolution step 97: f(x)= 13444.58453289771
# differential_evolution step 98: f(x)= 13444.58453289771
# differential_evolution step 99: f(x)= 13444.58453289771
# differential_evolution step 100: f(x)= 13444.58453289771
# differential_evolution step 101: f(x)= 13444.58453289771
# differential_evolution step 102: f(x)= 13444.58453289771
# differential_evolution step 103: f(x)= 13444.58453289771
# differential_evolution step 104: f(x)= 13444.58453289771
# differential_evolution step 105: f(x)= 13444.58453289771
# differential_evolution step 106: f(x)= 13444.58453289771
# differential_evolution step 107: f(x)= 13330.056431595158
# differential_evolution step 108: f(x)= 13330.056431595158
# differential_evolution step 109: f(x)= 13330.056431595158
# differential_evolution step 110: f(x)= 13330.056431595158
# differential_evolution step 111: f(x)= 13330.056431595158
# differential_evolution step 112: f(x)= 13330.056431595158
# differential_evolution step 113: f(x)= 13330.056431595158
# differential_evolution step 114: f(x)= 13330.056431595158
# differential_evolution step 115: f(x)= 13330.056431595158
# differential_evolution step 116: f(x)= 13330.056431595158
# differential_evolution step 117: f(x)= 13330.056431595158
# differential_evolution step 118: f(x)= 13330.056431595158
# differential_evolution step 119: f(x)= 13330.056431595158
# differential_evolution step 120: f(x)= 13330.056431595158
# differential_evolution step 121: f(x)= 13330.056431595158
# differential_evolution step 122: f(x)= 13330.056431595158
# differential_evolution step 123: f(x)= 13330.056431595158
# differential_evolution step 124: f(x)= 13330.056431595158
# differential_evolution step 125: f(x)= 13330.056431595158
# differential_evolution step 126: f(x)= 13330.056431595158
# differential_evolution step 127: f(x)= 13330.056431595158
# differential_evolution step 128: f(x)= 13330.056431595158
# differential_evolution step 129: f(x)= 13330.056431595158
# differential_evolution step 130: f(x)= 13330.056431595158
# differential_evolution step 131: f(x)= 13330.056431595158
# differential_evolution step 132: f(x)= 13330.056431595158
# differential_evolution step 133: f(x)= 13207.135758966648
# differential_evolution step 134: f(x)= 13207.135758966648
# differential_evolution step 135: f(x)= 13207.135758966648
# differential_evolution step 136: f(x)= 13207.135758966648
# differential_evolution step 137: f(x)= 13207.135758966648
# differential_evolution step 138: f(x)= 13207.135758966648
# differential_evolution step 139: f(x)= 13140.17766044364
# differential_evolution step 140: f(x)= 13140.17766044364
# differential_evolution step 141: f(x)= 13140.17766044364
# differential_evolution step 142: f(x)= 13140.17766044364
# differential_evolution step 143: f(x)= 13140.17766044364
# differential_evolution step 144: f(x)= 13140.17766044364
# differential_evolution step 145: f(x)= 13140.17766044364
# differential_evolution step 146: f(x)= 13140.17766044364
# differential_evolution step 147: f(x)= 13140.17766044364
# differential_evolution step 148: f(x)= 13140.17766044364
# differential_evolution step 149: f(x)= 13140.17766044364
# differential_evolution step 150: f(x)= 13140.17766044364
# differential_evolution step 151: f(x)= 13140.17766044364
# differential_evolution step 152: f(x)= 13140.17766044364
# differential_evolution step 153: f(x)= 13140.17766044364
# differential_evolution step 154: f(x)= 13140.17766044364
# differential_evolution step 155: f(x)= 13140.17766044364
# differential_evolution step 156: f(x)= 13140.17766044364
# differential_evolution step 157: f(x)= 13124.201233215488
# differential_evolution step 158: f(x)= 13124.201233215488
# differential_evolution step 159: f(x)= 13124.201233215488
# differential_evolution step 160: f(x)= 13124.201233215488
# differential_evolution step 161: f(x)= 12951.356774322287
# differential_evolution step 162: f(x)= 12951.356774322287
# differential_evolution step 163: f(x)= 12578.787971493623
# differential_evolution step 164: f(x)= 12578.787971493623
# differential_evolution step 165: f(x)= 12578.787971493623
# differential_evolution step 166: f(x)= 12578.787971493623
# differential_evolution step 167: f(x)= 12578.787971493623
# differential_evolution step 168: f(x)= 12578.787971493623
# differential_evolution step 169: f(x)= 12578.787971493623
# differential_evolution step 170: f(x)= 12519.285049689852
# differential_evolution step 171: f(x)= 12486.635980257433
# differential_evolution step 172: f(x)= 12486.635980257433
# differential_evolution step 173: f(x)= 12486.635980257433
# differential_evolution step 174: f(x)= 12486.635980257433
# differential_evolution step 175: f(x)= 12486.635980257433
# differential_evolution step 176: f(x)= 12486.635980257433
# differential_evolution step 177: f(x)= 12486.635980257433
# differential_evolution step 178: f(x)= 12486.635980257433
# differential_evolution step 179: f(x)= 12486.635980257433
# differential_evolution step 180: f(x)= 12413.944860919557
# differential_evolution step 181: f(x)= 12413.944860919557
# differential_evolution step 182: f(x)= 12413.944860919557
# differential_evolution step 183: f(x)= 12413.944860919557
# differential_evolution step 184: f(x)= 12384.671888059383
# differential_evolution step 185: f(x)= 12384.671888059383
# differential_evolution step 186: f(x)= 12330.692164660017
# differential_evolution step 187: f(x)= 12330.692164660017
# differential_evolution step 188: f(x)= 12157.88534260229
# differential_evolution step 189: f(x)= 12157.88534260229
# differential_evolution step 190: f(x)= 12157.88534260229
# differential_evolution step 191: f(x)= 12157.88534260229
# differential_evolution step 192: f(x)= 12157.88534260229
# differential_evolution step 193: f(x)= 12157.88534260229
# differential_evolution step 194: f(x)= 12152.061518445349
# differential_evolution step 195: f(x)= 12152.061518445349
# differential_evolution step 196: f(x)= 12148.920468017937
# differential_evolution step 197: f(x)= 12148.920468017937
# differential_evolution step 198: f(x)= 12148.920468017937
# differential_evolution step 199: f(x)= 12114.292424048126
# differential_evolution step 200: f(x)= 12110.843943200096
# differential_evolution step 201: f(x)= 12110.843943200096
# differential_evolution step 202: f(x)= 12093.123690739434
# differential_evolution step 203: f(x)= 12077.380090677792
# differential_evolution step 204: f(x)= 12077.380090677792
# differential_evolution step 205: f(x)= 12072.316767438517
# differential_evolution step 206: f(x)= 12037.751354965392
# differential_evolution step 207: f(x)= 12037.751354965392
# differential_evolution step 208: f(x)= 12012.949853175638
# differential_evolution step 209: f(x)= 12012.949853175638
# differential_evolution step 210: f(x)= 11995.60617631124
# differential_evolution step 211: f(x)= 11995.60617631124
# differential_evolution step 212: f(x)= 11986.194260646247
# differential_evolution step 213: f(x)= 11986.194260646247
# differential_evolution step 214: f(x)= 11986.194260646247
# differential_evolution step 215: f(x)= 11982.838004951886
# differential_evolution step 216: f(x)= 11982.838004951886
# differential_evolution step 217: f(x)= 11982.838004951886
# differential_evolution step 218: f(x)= 11965.089656305496
# differential_evolution step 219: f(x)= 11964.499438447028
# differential_evolution step 220: f(x)= 11964.499438447028
# differential_evolution step 221: f(x)= 11964.499438447028
# differential_evolution step 222: f(x)= 11964.499438447028
# differential_evolution step 223: f(x)= 11963.0146554194
# differential_evolution step 224: f(x)= 11963.0146554194
# differential_evolution step 225: f(x)= 11960.459594369966
# differential_evolution step 226: f(x)= 11938.327137242151
# differential_evolution step 227: f(x)= 11938.327137242151
# differential_evolution step 228: f(x)= 11938.327137242151
# differential_evolution step 229: f(x)= 11932.604346864398
# differential_evolution step 230: f(x)= 11932.604346864398
# differential_evolution step 231: f(x)= 11932.604346864398
# differential_evolution step 232: f(x)= 11912.858096047985
# differential_evolution step 233: f(x)= 11912.858096047985
# differential_evolution step 234: f(x)= 11912.858096047985
# differential_evolution step 235: f(x)= 11912.858096047985
# differential_evolution step 236: f(x)= 11908.429303166484
# differential_evolution step 237: f(x)= 11908.429303166484
# differential_evolution step 238: f(x)= 11908.429303166484
# differential_evolution step 239: f(x)= 11908.429303166484
# differential_evolution step 240: f(x)= 11900.492515588343
# differential_evolution step 241: f(x)= 11900.492515588343
# differential_evolution step 242: f(x)= 11898.993321697104
# differential_evolution step 243: f(x)= 11898.993321697104
# differential_evolution step 244: f(x)= 11898.993321697104
# differential_evolution step 245: f(x)= 11888.205552774534
# differential_evolution step 246: f(x)= 11888.205552774534
# differential_evolution step 247: f(x)= 11888.205552774534
# differential_evolution step 248: f(x)= 11888.205552774534
# differential_evolution step 249: f(x)= 11888.205552774534
# differential_evolution step 250: f(x)= 11888.205552774534
# differential_evolution step 251: f(x)= 11888.205552774534
# differential_evolution step 252: f(x)= 11888.205552774534
# differential_evolution step 253: f(x)= 11888.205552774534
# differential_evolution step 254: f(x)= 11875.597584860165
# differential_evolution step 255: f(x)= 11875.597584860165
# differential_evolution step 256: f(x)= 11875.597584860165
# differential_evolution step 257: f(x)= 11875.597584860165
# differential_evolution step 258: f(x)= 11875.597584860165
# differential_evolution step 259: f(x)= 11866.455516711323
# differential_evolution step 260: f(x)= 11866.455516711323
# differential_evolution step 261: f(x)= 11866.455516711323
# differential_evolution step 262: f(x)= 11866.455516711323
# differential_evolution step 263: f(x)= 11866.455516711323
# differential_evolution step 264: f(x)= 11866.455516711323
# differential_evolution step 265: f(x)= 11866.455516711323
# differential_evolution step 266: f(x)= 11861.746019710206
# differential_evolution step 267: f(x)= 11861.746019710206
# differential_evolution step 268: f(x)= 11861.746019710206
# differential_evolution step 269: f(x)= 11861.746019710206
# differential_evolution step 270: f(x)= 11853.042862957149
# differential_evolution step 271: f(x)= 11853.042862957149
# differential_evolution step 272: f(x)= 11853.042862957149
# differential_evolution step 273: f(x)= 11853.042862957149
# differential_evolution step 274: f(x)= 11853.042862957149
# differential_evolution step 275: f(x)= 11850.020502172603
# differential_evolution step 276: f(x)= 11850.020502172603
# differential_evolution step 277: f(x)= 11845.372939861505
# differential_evolution step 278: f(x)= 11845.372939861505
# differential_evolution step 279: f(x)= 11845.372939861505
# differential_evolution step 280: f(x)= 11845.372939861505
# differential_evolution step 281: f(x)= 11845.372939861505
# differential_evolution step 282: f(x)= 11845.372939861505
# differential_evolution step 283: f(x)= 11844.916144139635
# differential_evolution step 284: f(x)= 11840.653490938847
# differential_evolution step 285: f(x)= 11840.653490938847
# differential_evolution step 286: f(x)= 11840.653490938847
# differential_evolution step 287: f(x)= 11840.653490938847
# differential_evolution step 288: f(x)= 11840.653490938847
# differential_evolution step 289: f(x)= 11840.653490938847
# differential_evolution step 290: f(x)= 11840.653490938847
# differential_evolution step 291: f(x)= 11840.653490938847
# differential_evolution step 292: f(x)= 11840.653490938847
# differential_evolution step 293: f(x)= 11840.653490938847
# differential_evolution step 294: f(x)= 11835.889527435453
# differential_evolution step 295: f(x)= 11835.889527435453
# differential_evolution step 296: f(x)= 11832.860804684544
# differential_evolution step 297: f(x)= 11832.860804684544
# differential_evolution step 298: f(x)= 11832.860804684544
# differential_evolution step 299: f(x)= 11832.860804684544
# differential_evolution step 300: f(x)= 11829.19486356957
# differential_evolution step 301: f(x)= 11829.19486356957
# differential_evolution step 302: f(x)= 11825.794982358279
# differential_evolution step 303: f(x)= 11825.794982358279
# differential_evolution step 304: f(x)= 11825.794982358279
# differential_evolution step 305: f(x)= 11825.794982358279
# differential_evolution step 306: f(x)= 11825.794982358279
# differential_evolution step 307: f(x)= 11825.794982358279
# differential_evolution step 308: f(x)= 11825.794982358279
# differential_evolution step 309: f(x)= 11824.011603233585
# differential_evolution step 310: f(x)= 11824.011603233585
# differential_evolution step 311: f(x)= 11824.011603233585
# differential_evolution step 312: f(x)= 11823.697680976378
# differential_evolution step 313: f(x)= 11822.50972579287
# differential_evolution step 314: f(x)= 11819.711506888163
# differential_evolution step 315: f(x)= 11819.711506888163
# differential_evolution step 316: f(x)= 11819.711506888163
# differential_evolution step 317: f(x)= 11819.711506888163
# differential_evolution step 318: f(x)= 11819.711506888163
# differential_evolution step 319: f(x)= 11818.254396929964
# differential_evolution step 320: f(x)= 11818.254396929964
# differential_evolution step 321: f(x)= 11818.254396929964
# differential_evolution step 322: f(x)= 11818.254396929964
# differential_evolution step 323: f(x)= 11818.254396929964
# differential_evolution step 324: f(x)= 11818.254396929964
# differential_evolution step 325: f(x)= 11818.254396929964
# differential_evolution step 326: f(x)= 11817.428003577017
# differential_evolution step 327: f(x)= 11817.428003577017
# differential_evolution step 328: f(x)= 11817.036941831768
# differential_evolution step 329: f(x)= 11816.64066238568
# differential_evolution step 330: f(x)= 11816.64066238568
# differential_evolution step 331: f(x)= 11816.64066238568
# differential_evolution step 332: f(x)= 11816.64066238568
# differential_evolution step 333: f(x)= 11816.30265853269
# differential_evolution step 334: f(x)= 11816.30265853269
# differential_evolution step 335: f(x)= 11816.30265853269
# differential_evolution step 336: f(x)= 11815.434270031821
# differential_evolution step 337: f(x)= 11813.709453235535
# differential_evolution step 338: f(x)= 11813.709453235535
# differential_evolution step 339: f(x)= 11813.709453235535
# differential_evolution step 340: f(x)= 11813.709453235535
# differential_evolution step 341: f(x)= 11813.709453235535
# differential_evolution step 342: f(x)= 11813.51846745814
# differential_evolution step 343: f(x)= 11813.51846745814
# differential_evolution step 344: f(x)= 11813.51846745814
# differential_evolution step 345: f(x)= 11813.51846745814
# differential_evolution step 346: f(x)= 11813.51846745814
# differential_evolution step 347: f(x)= 11813.51846745814
# differential_evolution step 348: f(x)= 11813.51846745814
# differential_evolution step 349: f(x)= 11813.51846745814
# differential_evolution step 350: f(x)= 11813.51846745814
# differential_evolution step 351: f(x)= 11813.51846745814
# differential_evolution step 352: f(x)= 11813.512749750198
# differential_evolution step 353: f(x)= 11813.512749750198
# differential_evolution step 354: f(x)= 11813.512749750198
# differential_evolution step 355: f(x)= 11813.512749750198
# differential_evolution step 356: f(x)= 11813.512749750198
# differential_evolution step 357: f(x)= 11813.512749750198
# differential_evolution step 358: f(x)= 11813.455036156962
# differential_evolution step 359: f(x)= 11813.455036156962
# differential_evolution step 360: f(x)= 11813.390389736685
# differential_evolution step 361: f(x)= 11812.734809796637
# differential_evolution step 362: f(x)= 11812.734809796637
# differential_evolution step 363: f(x)= 11812.734809796637
# differential_evolution step 364: f(x)= 11812.734809796637
# differential_evolution step 365: f(x)= 11812.734809796637
# differential_evolution step 366: f(x)= 11812.734809796637
# differential_evolution step 367: f(x)= 11812.734809796637
# differential_evolution step 368: f(x)= 11812.734809796637
# differential_evolution step 369: f(x)= 11812.340933341231
# differential_evolution step 370: f(x)= 11812.340933341231
# differential_evolution step 371: f(x)= 11812.340933341231
# differential_evolution step 372: f(x)= 11812.340933341231
# differential_evolution step 373: f(x)= 11812.257746950705
# differential_evolution step 374: f(x)= 11812.093260935544
# differential_evolution step 375: f(x)= 11812.093260935544
# differential_evolution step 376: f(x)= 11812.093260935544
# differential_evolution step 377: f(x)= 11811.918471156647
# differential_evolution step 378: f(x)= 11811.918471156647
# differential_evolution step 379: f(x)= 11811.918471156647
# differential_evolution step 380: f(x)= 11811.918471156647
# differential_evolution step 381: f(x)= 11811.918471156647
# differential_evolution step 382: f(x)= 11811.918471156647
# differential_evolution step 383: f(x)= 11811.918471156647
# differential_evolution step 384: f(x)= 11811.918471156647
# differential_evolution step 385: f(x)= 11811.918471156647
# differential_evolution step 386: f(x)= 11811.918471156647
# differential_evolution step 387: f(x)= 11811.918471156647
# differential_evolution step 388: f(x)= 11811.425420682186
# differential_evolution step 389: f(x)= 11811.404152688207
# differential_evolution step 390: f(x)= 11811.404152688207
# differential_evolution step 391: f(x)= 11811.404152688207
# differential_evolution step 392: f(x)= 11811.404152688207
# differential_evolution step 393: f(x)= 11811.404152688207
# differential_evolution step 394: f(x)= 11811.404152688207
# differential_evolution step 395: f(x)= 11811.404152688207
# differential_evolution step 396: f(x)= 11811.404152688207
# differential_evolution step 397: f(x)= 11811.404152688207
# differential_evolution step 398: f(x)= 11811.404152688207
# differential_evolution step 399: f(x)= 11811.404152688207
# differential_evolution step 400: f(x)= 11811.398527742775
# differential_evolution step 401: f(x)= 11811.398527742775
# differential_evolution step 402: f(x)= 11811.398527742775
# differential_evolution step 403: f(x)= 11811.398527742775
# differential_evolution step 404: f(x)= 11811.237873284254
# differential_evolution step 405: f(x)= 11811.079435422254
# differential_evolution step 406: f(x)= 11811.079435422254
# differential_evolution step 407: f(x)= 11811.079435422254
# differential_evolution step 408: f(x)= 11811.079435422254
# differential_evolution step 409: f(x)= 11811.012394319498
# differential_evolution step 410: f(x)= 11811.004879943375
# differential_evolution step 411: f(x)= 11811.004879943375
# differential_evolution step 412: f(x)= 11811.003784947225
# differential_evolution step 413: f(x)= 11811.003784947225
# differential_evolution step 414: f(x)= 11811.003784947225
# differential_evolution step 415: f(x)= 11810.87309313186
# differential_evolution step 416: f(x)= 11810.87309313186
# differential_evolution step 417: f(x)= 11810.87309313186
# differential_evolution step 418: f(x)= 11810.87309313186
# differential_evolution step 419: f(x)= 11810.87309313186
# differential_evolution step 420: f(x)= 11810.87309313186
# differential_evolution step 421: f(x)= 11810.87309313186
# differential_evolution step 422: f(x)= 11810.87309313186
# differential_evolution step 423: f(x)= 11810.87309313186
# differential_evolution step 424: f(x)= 11810.87309313186
# differential_evolution step 425: f(x)= 11810.87309313186
# differential_evolution step 426: f(x)= 11810.87309313186
# differential_evolution step 427: f(x)= 11810.87309313186
# differential_evolution step 428: f(x)= 11810.87309313186
# differential_evolution step 429: f(x)= 11810.87309313186
# differential_evolution step 430: f(x)= 11810.87309313186
# differential_evolution step 431: f(x)= 11810.82211149045
# differential_evolution step 432: f(x)= 11810.82211149045
# differential_evolution step 433: f(x)= 11810.82211149045
# differential_evolution step 434: f(x)= 11810.82211149045
# differential_evolution step 435: f(x)= 11810.82211149045
# differential_evolution step 436: f(x)= 11810.82211149045
# differential_evolution step 437: f(x)= 11810.82211149045
# differential_evolution step 438: f(x)= 11810.82211149045
# differential_evolution step 439: f(x)= 11810.82211149045
# differential_evolution step 440: f(x)= 11810.82211149045
# differential_evolution step 441: f(x)= 11810.82211149045
# differential_evolution step 442: f(x)= 11810.801064363943
# differential_evolution step 443: f(x)= 11810.801064363943
# differential_evolution step 444: f(x)= 11810.692126190492
# differential_evolution step 445: f(x)= 11810.692126190492
# differential_evolution step 446: f(x)= 11810.692126190492
# differential_evolution step 447: f(x)= 11810.692126190492
# differential_evolution step 448: f(x)= 11810.692126190492
# differential_evolution step 449: f(x)= 11810.692126190492
# differential_evolution step 450: f(x)= 11810.692126190492
# differential_evolution step 451: f(x)= 11810.692126190492
# differential_evolution step 452: f(x)= 11810.692126190492
# differential_evolution step 453: f(x)= 11810.684126915836
# differential_evolution step 454: f(x)= 11810.684126915836
# differential_evolution step 455: f(x)= 11810.626369828024
# differential_evolution step 456: f(x)= 11810.626369828024
# differential_evolution step 457: f(x)= 11810.626369828024
# differential_evolution step 458: f(x)= 11810.626369828024
# differential_evolution step 459: f(x)= 11810.626369828024
# differential_evolution step 460: f(x)= 11810.626369828024
# differential_evolution step 461: f(x)= 11810.626369828024
# differential_evolution step 462: f(x)= 11810.587938754703
# differential_evolution step 463: f(x)= 11810.587938754703
# differential_evolution step 464: f(x)= 11810.562989294971
# differential_evolution step 465: f(x)= 11810.562989294971
# differential_evolution step 466: f(x)= 11810.562989294971
# differential_evolution step 467: f(x)= 11810.562989294971
# differential_evolution step 468: f(x)= 11810.562989294971
# differential_evolution step 469: f(x)= 11810.562989294971
# differential_evolution step 470: f(x)= 11810.562989294971
# differential_evolution step 471: f(x)= 11810.562989294971
# differential_evolution step 472: f(x)= 11810.562989294971
# differential_evolution step 473: f(x)= 11810.562989294971
# differential_evolution step 474: f(x)= 11810.562989294971
# differential_evolution step 475: f(x)= 11810.562989294971
# differential_evolution step 476: f(x)= 11810.562989294971
# differential_evolution step 477: f(x)= 11810.562989294971
# differential_evolution step 478: f(x)= 11810.562989294971
# differential_evolution step 479: f(x)= 11810.562539659817
# differential_evolution step 480: f(x)= 11810.562539659817
# differential_evolution step 481: f(x)= 11810.562539659817
# differential_evolution step 482: f(x)= 11810.56148209376
# differential_evolution step 483: f(x)= 11810.56148209376
# differential_evolution step 484: f(x)= 11810.56148209376
# differential_evolution step 485: f(x)= 11810.531179542777
# differential_evolution step 486: f(x)= 11810.531179542777
# differential_evolution step 487: f(x)= 11810.531179542777
# differential_evolution step 488: f(x)= 11810.531179542777
# differential_evolution step 489: f(x)= 11810.531179542777
# differential_evolution step 490: f(x)= 11810.531179542777
# differential_evolution step 491: f(x)= 11810.531179542777
# differential_evolution step 492: f(x)= 11810.531179542777
# differential_evolution step 493: f(x)= 11810.531179542777
# differential_evolution step 494: f(x)= 11810.531179542777
# differential_evolution step 495: f(x)= 11810.531179542777
# differential_evolution step 496: f(x)= 11810.520918326732
# differential_evolution step 497: f(x)= 11810.520918326732
# differential_evolution step 498: f(x)= 11810.520918326732
# differential_evolution step 499: f(x)= 11810.520918326732
# differential_evolution step 500: f(x)= 11810.520918326732
# differential_evolution step 501: f(x)= 11810.516982005438
# differential_evolution step 502: f(x)= 11810.516982005438
# differential_evolution step 503: f(x)= 11810.516982005438
# differential_evolution step 504: f(x)= 11810.516982005438
# differential_evolution step 505: f(x)= 11810.516982005438
# differential_evolution step 506: f(x)= 11810.516982005438
# differential_evolution step 507: f(x)= 11810.49986851905
# differential_evolution step 508: f(x)= 11810.49986851905
# differential_evolution step 509: f(x)= 11810.49986851905
# differential_evolution step 510: f(x)= 11810.49986851905
# differential_evolution step 511: f(x)= 11810.49986851905
# differential_evolution step 512: f(x)= 11810.49986851905
# differential_evolution step 513: f(x)= 11810.49986851905
# differential_evolution step 514: f(x)= 11810.49986851905
# differential_evolution step 515: f(x)= 11810.49986851905
# differential_evolution step 516: f(x)= 11810.49800875263
# differential_evolution step 517: f(x)= 11810.483038582553
# differential_evolution step 518: f(x)= 11810.483038582553
# differential_evolution step 519: f(x)= 11810.483038582553
# differential_evolution step 520: f(x)= 11810.483038582553
# differential_evolution step 521: f(x)= 11810.479273235902
# differential_evolution step 522: f(x)= 11810.479273235902
# differential_evolution step 523: f(x)= 11810.474635865026
# differential_evolution step 524: f(x)= 11810.474635865026
# differential_evolution step 525: f(x)= 11810.474635865026
# differential_evolution step 526: f(x)= 11810.474635865026
# differential_evolution step 527: f(x)= 11810.474635865026
# differential_evolution step 528: f(x)= 11810.474635865026
# differential_evolution step 529: f(x)= 11810.474635865026
# differential_evolution step 530: f(x)= 11810.473921581057
# differential_evolution step 531: f(x)= 11810.473921581057
# differential_evolution step 532: f(x)= 11810.473921581057
# differential_evolution step 533: f(x)= 11810.473921581057
# differential_evolution step 534: f(x)= 11810.473921581057
# differential_evolution step 535: f(x)= 11810.473921581057
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.5000, r_e=50.0000, n=3.3396, x_0=38.5080
# Sérsic 2: I_e=1.5000, r_e=1.0000, n=4.0000, x_0=47.9775
# Sérsic 3: I_e=1.5000, r_e=20.0000, n=2.4407, x_0=80.9280
# Chi quadro minimo: 11810.473921581057
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 20)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 20)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_3, r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(model_convolved, x_axes, radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3)

chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
    radial_profile_error_continuum_3, x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
# Out:
# Sérsic 1: I_e=0.8171, r_e=101.8131, n=3.5814, x_0=38.2791
# Sérsic 2: I_e=0.8631, r_e=33.4293, n=2.9047, x_0=47.9775
# Sérsic 3: I_e=0.2819, r_e=71.6871, n=3.5597, x_0=80.9284
# [9.33118150e-01 1.04649756e+02 8.02733513e-01 8.13931553e-02
#  5.04374899e+00 1.54275392e+02 4.91807037e+00 6.60401958e-03
#  1.47424649e+00 2.88290520e+02 4.35725086e+00 1.03663017e-01]
# 1121.761175962111

# %%
plot_diff(x_axes, params_curve_continuum_3, radial_profile_continuum_3, r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
