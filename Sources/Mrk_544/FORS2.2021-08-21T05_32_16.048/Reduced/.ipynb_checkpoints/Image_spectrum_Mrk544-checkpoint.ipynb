# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_29_16.174.fits") #image
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Mrk-544_MAPPED_FLUX_SCI_LSS_U1.fits") #spectrum
image_data = hdul[0].data
image_data_2 = hdul2[0].data
image_error_2 = hdul2[1].data

# %%
image_cut = image_data[58:158, 1050:1200]
image_cut_2 = image_data_2[55:155, 0:1890] 
image_error_cut_2 = image_error_2[55:155, 0:1890]

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, params):
    """ Profilo Sérsic 1D centrato in x_0 """
    I_e, r_e, n, x_0 = params
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, params1, params2, params3, params4):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, params1) +
        sersic_1d(x_hr, params2) +
        sersic_1d(x_hr, params3) +
        sersic_1d(x_hr, params4) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def sersic_1d_convolved(x, sigma, params):
    """ Sérsic convoluto con PSF gaussiana """
    I_e, r_e, n, x_0 = params
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, params)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

# %%
z = 0.0238
l_HA = 6563 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/PSF/Real_seeing_Mrk544.txt")
sigmas = seeing / 2.35

wavelenghts = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
mask_HA = (wavelenghts > l_HA-8)*(wavelenghts < l_HA+8)
image_HA = image_cut_2[:, mask_HA]
image_error_HA = image_error_cut_2[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))
sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Propagazione_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
fit = pd.read_csv("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Fit_code/Halpha_fit.csv", index_col=0)

# %%
arcsec_x = np.arange(-61*0.252, 89*0.252, 0.252)
arcsec_y = np.arange(-58*0.252, 42*0.252, 0.252)
#x_grid, y_grid = np.meshgrid(arcsec_x, arcsec_y)
#x_grid_2, y_grid_2 = np.meshgrid(wavelenghts, arcsec_y)
J, N = image_cut.shape
x = np.arange(0, N, 1)
y = np.arange(0, J, 1)

x_grid, y_grid = np.meshgrid(arcsec_x, arcsec_y)

J_2, N_2 = image_cut_2.shape
x_2 = np.arange(0, N_2, 1)
y_2 = np.arange(0, J_2, 1)

x_grid_2, y_grid_2 = np.meshgrid(wavelenghts, arcsec_y)

y_fit = model_convolved(x_axes, sigmas[0], fit['Component 1'], fit['Component 2'], 
                           fit['Component 3'], fit['Component 4'])

fig, ax = plt.subplots(1, 3, figsize=(25, 7), 
                      gridspec_kw={'width_ratios': [1, 2, 2], 'wspace': 0.01},
                      sharey=True)
fig.suptitle('Mrk 544', fontsize=30)


ax[0].errorbar(radial_profile_HA, arcsec_y, xerr = radial_profile_error_HA, label='Data')

colors = ['b', 'g', 'm', 'orange'] 
components = ['Component 1', 'Component 2', 'Component 3', 'Component 4']
for i, comp_name in enumerate(components):
        color = colors[i]
        
        y_comp = sersic_1d_convolved(x_axes, sigmas[0], np.array(fit[comp_name]))
        ax[0].plot(y_comp, arcsec_y, '--', color=color,  
                  label=f'Sérsic {i+1}')
    
ax[0].set_xlabel(r'Flux [$10^{-16}$ erg/(cm$^2$ s Å)]', fontsize=12)
#ax[0].legend(loc='upper right', fontsize=13)
ax[0].grid(True, alpha=0.3)
ax[0].invert_xaxis()
xlim = ax[0].get_xlim()
ax[0].hlines(y=-5.56, xmin=11.78, xmax = xlim[1],  color='blue', linewidth=2, linestyle = '--')
ax[0].hlines(y=-3.91, xmin=4.18, xmax = xlim[1],  color='g', linewidth=2, linestyle = '--')
ax[0].hlines(y=0.41, xmin=5.23, xmax = xlim[1],  color='m', linewidth=2, linestyle = '--')
ax[0].hlines(y=3.69, xmin=0.91, xmax = xlim[1],  color='orange', linewidth=2, linestyle = '--')
ax[0].set_xlim(xlim[0], xlim[1])

ax[1].pcolormesh(x_grid, y_grid, np.log10(image_cut), shading='nearest', vmin=np.log10(3500), vmax=np.log10(5800), cmap = 'viridis') #hot: 2500, 6000

# Leggi il WCS dall'header dell'immagine
wcs = WCS(hdul[0].header)

# Calcola l'orientamento del Nord
ny, nx = image_cut.shape
x_center, y_center = nx / 2, ny / 2

# Converti le coordinate pixel in coordinate world
# Nota: devi usare le coordinate ORIGINALI prima del taglio
x_orig_center = 1050 + x_center
y_orig_center = 58 + y_center

coord_center = wcs.pixel_to_world(x_orig_center, y_orig_center)
coord_up = wcs.pixel_to_world(x_orig_center, y_orig_center + 50)

# Calcola l'angolo di posizione del nord
pa = coord_center.position_angle(coord_up).deg

# Posizione delle frecce nell'immagine tagliata (angolo in alto a destra)
# In coordinate arcsec
x_arrow = 17  # arcsec dalla posizione di riferimento
y_arrow = 5   # arcsec dalla posizione di riferimento
arrow_len = 2  # arcsec

# Converti l'angolo in radianti e calcola i componenti delle frecce
# Freccia Nord
dx_n = arrow_len * np.sin(np.radians(pa))
dy_n = arrow_len * np.cos(np.radians(pa))

ax[1].arrow(x_arrow, y_arrow, dx_n, dy_n,
            head_width=0.6, head_length=0.5,
            fc='white', ec='white', linewidth=1)
ax[1].text(x_arrow + dx_n * 1.6, y_arrow + dy_n * 1.6, 'N',
           ha='center', va='center', color='white',
           fontsize=14) #, fontweight='bold')

# Freccia Est (perpendicolare al nord, -90°)
dx_e = arrow_len * np.sin(np.radians(pa - 90))
dy_e = arrow_len * np.cos(np.radians(pa - 90))

ax[1].arrow(x_arrow, y_arrow, dx_e, dy_e,
            head_width=0.6, head_length=0.5,
            fc='white', ec='white', linewidth=1)
ax[1].text(x_arrow + dx_e * 1.6, y_arrow + dy_e * 1.6, 'E',
           ha='center', va='center', color='white',
           fontsize=14) #, fontweight='bold')

# Coordinate in pixel dell'immagine ORIGINALE (2048x1034)
x_pixel_orig = 1125.7979  # esempio
y_pixel_orig = 128.86322   # esempio

# Converti in coordinate del taglio
x_cut = x_pixel_orig - 1050  # sottrai l'offset x del taglio
y_cut = y_pixel_orig - 58    # sottrai l'offset y del taglio

# Converti in arcsec
x_arcsec = arcsec_x[0] + x_cut * 0.252
y_arcsec = arcsec_y[0] + y_cut * 0.252

# Plotta
ax[1].plot(x_arcsec, y_arcsec, 'x', color='cyan', 
           markersize=20, markeredgewidth=3, label='NVSS radio detection')

ax[1].set_xlabel(r'$\Delta x$ [arcsec]')
ax[0].set_ylabel(r'$\Delta y$ [arcsec]')
ax[1].axvline(-0.35, color='red')
ax[1].axvline(0.35, color='red')
ax[1].tick_params(axis='both', which='both', direction='in', color = 'white', top=True, bottom=True, left=True, right=True, length = 6)
#ax[1].grid(True, alpha=0.3, color = 'white')
xlim = ax[1].get_xlim()
ax[1].hlines(y=-5.56, xmin =xlim[0],  xmax=-0.5, color='blue', linewidth=2, linestyle = '--')
ax[1].hlines(y=-3.91, xmin =xlim[0],  xmax=-0.5, color='g', linewidth=2, linestyle = '--')
ax[1].hlines(y=0.41, xmin =xlim[0],  xmax=-0.5, color='m', linewidth=2, linestyle = '--')
ax[1].hlines(y=3.69, xmin =xlim[0],  xmax=-0.5, color='orange', linewidth=2, linestyle = '--')
ax[1].set_xlim(xlim[0], xlim[1])

ax[2].pcolormesh(x_grid_2, y_grid_2, image_cut_2, shading='gouraud', vmin=np.percentile(image_cut_2, 5), vmax=np.percentile(image_cut_2, 95)) #altre opzioni
ax[2].set_xlabel(r'Wavelenght [$\AA$]')
ax[2].tick_params(axis='both', which='both', direction='in', color = 'white', top=True, bottom=True, left=True, right=True, length = 6)

ax[0].set_title(r'H$\alpha$ profile', fontsize=16)
ax[1].set_title('R band image', fontsize=16)
ax[2].set_title('2D spectrum', fontsize=16)
ax[1].legend(markerscale = 0.5, loc = 'lower right', framealpha =1, fontsize = 15)
plt.subplots_adjust(wspace=0.01)

fig.savefig("Mrk544_all_lines.png", bbox_inches='tight')
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'ESO INS SHUT EXPTIME' is not FITS standard (invalid value string: '9.998794e+00 / Real exposure time in sec.').  Fixed 'ESO INS SHUT EXPTIME' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'ESO INS IMAGE DISTOR1' is not FITS standard (invalid value string: '5.367470e-04 / distortion coefficient').  Fixed 'ESO INS IMAGE DISTOR1' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'ESO INS IMAGE DISTOR2' is not FITS standard (invalid value string: '-2.157780e-06 / distortion coefficient').  Fixed 'ESO INS IMAGE DISTOR2' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'ESO INS IMAGE DISTOR3' is not FITS standard (invalid value string: '2.113310e-09 / distortion coefficient').  Fixed 'ESO INS IMAGE DISTOR3' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Coordinate reference frame
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
arcsec_x = np.arange(-61*0.256, 89*0.256, 0.256)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)
#x_grid, y_grid = np.meshgrid(arcsec_x, arcsec_y)
#x_grid_2, y_grid_2 = np.meshgrid(wavelenghts, arcsec_y)
J, N = image_cut.shape
x = np.arange(0, N, 1)
y = np.arange(0, J, 1)

x_grid, y_grid = np.meshgrid(arcsec_x, arcsec_y)

J_2, N_2 = image_cut_2.shape
x_2 = np.arange(0, N_2, 1)
y_2 = np.arange(0, J_2, 1)

x_grid_2, y_grid_2 = np.meshgrid(wavelenghts, arcsec_y)

y_fit = model_convolved(x_axes, sigmas[0], fit['Component 1'], fit['Component 2'], 
                           fit['Component 3'], fit['Component 4'])

fig, ax = plt.subplots(1, 3, figsize=(25, 7), 
                      gridspec_kw={'width_ratios': [1, 2, 2], 'wspace': 0.01},
                      sharey=True)
fig.suptitle('Mrk 544', fontsize=30)

ax[0].errorbar(radial_profile_HA, arcsec_y, xerr = radial_profile_error_HA, label='Data')

colors = ['b', 'g', 'm', 'orange'] 
components = ['Component 1', 'Component 2', 'Component 3', 'Component 4']
for i, comp_name in enumerate(components):
        color = colors[i]
        
        y_comp = sersic_1d_convolved(x_axes, sigmas[0], np.array(fit[comp_name]))
        ax[0].plot(y_comp, arcsec_y, '--', color=color,  
                  label=f'Sérsic {i+1}')
    
ax[0].set_xlabel(r'Flux [$10^{-16}$ erg/(cm$^2$ s Å)]', fontsize=12)
#ax[0].legend(loc='upper right', fontsize=13)
ax[0].grid(True, alpha=0.3)
ax[0].invert_xaxis()

ax[1].pcolormesh(x_grid, y_grid, np.log10(image_cut), shading='nearest', vmin=np.log10(3500), vmax=np.log10(5800), cmap = 'viridis') #hot: 2500, 6000
ax[1].set_xlabel(r'$\Delta x$ [arcsec]')
ax[0].set_ylabel(r'$\Delta y$ [arcsec]')
ax[1].axvline(-0.35, color='red')
ax[1].axvline(0.35, color='red')
ax[1].tick_params(axis='both', which='both', direction='in', color = 'white', top=True, bottom=True, left=True, right=True, length = 6)
#ax[1].grid(True, alpha=0.3, color = 'white')

ax[2].pcolormesh(x_grid_2, y_grid_2, image_cut_2, shading='gouraud', vmin=np.percentile(image_cut_2, 5), vmax=np.percentile(image_cut_2, 95)) #altre opzioni
ax[2].set_xlabel(r'Wavelenght [$\AA$]')
ax[2].tick_params(axis='both', which='both', direction='in', color = 'white', top=True, bottom=True, left=True, right=True, length = 6)
plt.subplots_adjust(wspace=0.01)

fig.savefig("Mrk544_all.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CRVAL : 1.1979 -1.50269
# CRPIX : 1023.0 118.1
# CD1_1 CD1_2  : 5.118167e-05 4.772768e-05
# CD2_1 CD2_2  : 4.772768e-05 -5.118167e-05
# NAXIS : 2048  1034

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T          / Standard FITS format (NOST-100.0)
# BITPIX  =                   16          / # of bits storing pix values
# NAXIS   =                    2          / # of axes in frame
# NAXIS1  =                 2048          / # pixels/axis
# NAXIS2  =                 1034          / # pixels/axis
# ORIGIN  = 'ESO     '                    / European Southern Observatory
# DATE    = '2021-08-21T05:29:29.345'     / UT date when this file was written
# MJD-OBS =       59447.22865941          / MJD start (2021-08-21T05:29:16.173)
# DATE-OBS= '2021-08-21T05:29:16.173'     / Date of observation
# EXPTIME =               9.9988          / Total integration time
# CRVAL1  =              1.19790          / value of ref pixel
# CRPIX1  =               1023.0          / Ref pixel in x-axis
# CTYPE1  = 'RA---TAN'                    / Coordinate system of x-axis
# CRVAL2  =             -1.50269          / value of ref pixel
# CRPIX2  =                118.1          / Ref pixel in y-axis
# CTYPE2  = 'DEC--TAN'                    / Coordinate system of y-axis
# BSCALE  =          1.000000000          / pixel=FITS*BSCALE+BZERO
# BZERO   =              32768.0          / pixel=FITS*BSCALE+BZERO
# INHERIT =                    T          / denotes the INHERIT keyword convention
# EXTNAME = 'CHIP1   '                    / Extension name
# TELESCOP= 'ESO-VLT-U1'                  / ESO Telescope Name
# RA      =             1.197904          / 00:04:47.4 RA (J2000) pointing
# DEC     =             -1.50269          / -01:30:09.6 DEC (J2000) pointing
# EQUINOX =               2000.0          / Standard FK5
# RADECSYS= 'FK5     '                    / Coordinate reference frame
# LST     =            82000.201          / 22:46:40.201 LST at start
# UTC     =            19755.000          / 05:29:15.000 UTC at start
# OBJECT  = 'Mrk 544 '                    / Target description
# INSTRUME= 'FORS2   '                    / Instrument used
# CD1_1   =      5.118167000E-05          / Translation matrix element.
# CD1_2   =      4.772768000E-05          / Translation matrix element.
# CD2_1   =      4.772768000E-05          / Translation matrix element.
# CD2_2   =     -5.118167000E-05          / Translation matrix element.
# HIERARCH ESO OBS NTPL        =            3 / Number of templates within OB
# HIERARCH ESO OBS TPLNO       =            1 / Template number within OB
# HIERARCH ESO OBS NAME        = 'Mrk-544 '   / OB name
# HIERARCH ESO OBS PROG ID     = '108.2222.001' / ESO program identification
# HIERARCH ESO OBS ID          =      3059000 / Observation block ID
# HIERARCH ESO OBS DID         = 'ESO-VLT-DIC.OBS-2.2' / OBS Dictionary
# HIERARCH ESO OBS OBSERVER    = 'UNKNOWN '   / Observer Name
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN '   / PI-COI name
# HIERARCH ESO OBS PI-COI ID   =         6393 / ESO internal PI-COI ID
# HIERARCH ESO OBS TARG NAME   = 'Mrk 544 '   / OB target name
# HIERARCH ESO OBS GRP         = '0       '   / linked blocks
# HIERARCH ESO OBS START       = '2021-08-21T05:23:43' / OB start time
# HIERARCH ESO OBS EXECTIME    =         2033 / Expected execution time
# HIERARCH ESO OBS CONTAINER ID=         -999 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE= 'U       ' / Scheduling container type
# HIERARCH ESO OBS MOON FLI    =          1.0 / Req. max. fractional lunar illum.
# HIERARCH ESO OBS MOON DIST   =           30 / Req. min. angular dist. from moon
# HIERARCH ESO OBS AMBI FWHM   =          0.8 / Req. max. seeing
# HIERARCH ESO OBS TWILIGHT    =            0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR =         30.0 / Req. water vapour
# HIERARCH ESO OBS AMBI TRANS  = '2CLR    '   / Req. sky transparency
# HIERARCH ESO OBS AIRM        =          1.4 / Req. max. airmass
# HIERARCH ESO OBS AOMODE      = 'NO_AO   '   / Req. AO mode
# HIERARCH ESO TPL ID          = 'FORS2_lss_acq_fast' / Template signature ID
# HIERARCH ESO TPL NAME        = 'Long slit alignment without fims.' / Template na
# HIERARCH ESO TPL NEXP        =            2 / Number of exposures within templat
# HIERARCH ESO TPL EXPNO       =            2 / Exposure number within template
# HIERARCH ESO TPL START       = '2021-08-21T05:23:43' / TPL start time
# HIERARCH ESO DPR CATG        = 'ACQUISITION' / Observation category
# HIERARCH ESO DPR TYPE        = 'SKY     '   / Observation type
# HIERARCH ESO DPR TECH        = 'IMAGE   '   / Observation technique
# HIERARCH ESO TEL DID         = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL ID          = 'v 329893'   / TCS version number
# HIERARCH ESO TEL DATE        = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL ALT         =       59.895 / Alt angle at start
# HIERARCH ESO TEL AZ          =      222.471 / Az angle at start S=0,W=90
# HIERARCH ESO TEL GEOELEV     =       2648.0 / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT      =     -24.6276 / Tel geo latitute (+=North)
# HIERARCH ESO TEL GEOLON      =     -70.4051 / Tel geo longitude (+=East)
# HIERARCH ESO TEL OPER        = 'I, Condor'  / Telescope Operator
# HIERARCH ESO TEL FOCU ID     = 'CA      '   / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN    =      108.827 / Focal length
# HIERARCH ESO TEL FOCU SCALE  =        1.894 / Focal scale
# HIERARCH ESO TEL FOCU VALUE  =       -6.137 / M2 setting
# HIERARCH ESO TEL PARANG START=     -142.127 / Parallactic angle at start
# HIERARCH ESO TEL AIRM START  =        1.156 / Airmass at start
# HIERARCH ESO TEL AMBI FWHM START=      0.36 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES START=    743.40 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI WINDSP =         3.15 / Observatory ambient wind speed que
# HIERARCH ESO TEL AMBI WINDDIR=         11.0 / Observatory ambient wind direction
# HIERARCH ESO TEL AMBI RHUM   =         16.5 / Observatory ambient relative humid
# HIERARCH ESO TEL AMBI TEMP   =        13.44 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI IWV START=       2.43 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWVSTD START=    0.01 / Standard Deviation of Integrated W
# HIERARCH ESO TEL AMBI IWV30D START=    2.42 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD START= 0.01 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IRSKY TEMP=     -95.8 / Temperature of the IR sky, from ra
# HIERARCH ESO TEL MOON RA     =   315.454097 / 21:01:48.9 RA (J2000)
# HIERARCH ESO TEL MOON DEC    =    -21.45075 / -21:27:02.6 DEC (J2000)
# HIERARCH ESO TEL TH M1 TEMP  =        10.96 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  '   / Tracking status
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL CHOP ST     =            F / True when chopping is active
# HIERARCH ESO TEL FO POS      =     0.000000 / Adapter focus position during trac
# HIERARCH ESO TEL TARG ALPHA  =      448.627 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG DELTA  =   -12954.330 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH  =     2000.000 / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM= 'J       ' / Epoch system (default J=Julian)
# HIERARCH ESO TEL TARG EQUINOX=     2000.000 / Equinox
# HIERARCH ESO TEL TARG PMA    =     0.000000 / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD    =     0.000000 / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL =        0.000 / Radial velocity
# HIERARCH ESO TEL TARG PARALLAX=       0.000 / Parallax
# HIERARCH ESO TEL TARG COORDTYPE= 'M       ' / Coordinate type (M=mean A=apparent
# HIERARCH ESO TEL PARANG END  =     -142.195 / Parallactic angle at end
# HIERARCH ESO TEL AIRM END    =        1.155 / Airmass at end
# HIERARCH ESO TEL AMBI FWHM END=        0.36 / Observatory Seeing queried from AS
# HIERARCH ESO TEL IA FWHM     =         0.70 / Delivered seeing corrected by airm
# HIERARCH ESO TEL IA FWHMLIN  =         0.77 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL IA FWHMLINOBS=        0.84 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL AMBI PRES END=      743.40 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI IWV END=         2.43 / Integrated Water Vapor
# HIERARCH ESO TEL AMBI IWVSTD END=      0.01 / Standard Deviation of Integrated W
# HIERARCH ESO TEL AMBI IWV30D END=      2.42 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI IWV30DSTD END=   0.01 / IWV at 30deg elev.
# HIERARCH ESO TEL AMBI TAU0   =       0.0097 / Average coherence time
# HIERARCH ESO TEL LADC TARGSEPPOS=     666.2 / LADC target separation distance
# HIERARCH ESO ADA ABSROT START=    -98.54099 / Abs rot angle at exp start
# HIERARCH ESO ADA POSANG      =   -137.00000 / Position angle at start
# HIERARCH ESO ADA GUID STATUS = 'ON      '   / Status of autoguider
# HIERARCH ESO ADA GUID RA     =     1.221662 / 00:04:53.1 Guide star RA J2000
# HIERARCH ESO ADA GUID DEC    =     -1.39365 / -01:23:37.1 Guide star DEC J2000
# HIERARCH ESO ADA ABSROT PPOS = 'POS     '   / sign of probe position
# HIERARCH ESO ADA ABSROT END  =    -98.61362 / Abs rot angle at exp end
# HIERARCH ESO INS PIXSCALE    =        0.126 / pixel scale in arcsec/pixel
# HIERARCH ESO INS SHUT EXPTIME = 9.998794E+00 / Real exposure time in sec.
# HIERARCH ESO INS MODE        = 'LSS     '   / Instrument mode used
# HIERARCH ESO INS COLL ID     = '+6      '   / Collimator unique ID
# HIERARCH ESO INS COLL NAME   = 'COLL_SR '   / Collimator name
# HIERARCH ESO INS FILT1 ID    = '+76     '   / Filter unique ID
# HIERARCH ESO INS FILT1 NAME  = 'R_SPECIAL'  / Filter i name
# HIERARCH ESO INS FOCU POS    =   0.15120000 / Focus position in cm
# HIERARCH ESO INS FOCU TEMP   =         13.2 / Focus temperature in C
# HIERARCH ESO INS IMAGE DISTOR1 = 5.367470E-04 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR2 = -2.157780E-06 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR3 = 2.113310E-09 / distortion coefficient
# HIERARCH ESO INS OPTI2 NAME  = 'free    '   / Name of long slit or polarimetric
# HIERARCH ESO INS OPTI3 NAME  = 'COLL_SR '   / Name of collimator
# HIERARCH ESO INS OPTI4 NAME  = 'free    '   / Name of retarder plate
# HIERARCH ESO INS OPTI5 NAME  = 'free    '   / element name in wheel 1 (Wollaston
# HIERARCH ESO INS OPTI6 NAME  = 'free    '   / element name in wheel2 (grism)
# HIERARCH ESO INS OPTI7 NAME  = 'R_SPECIAL'  / element name in wheel3 (parallel b
# HIERARCH ESO INS OPTI8 NAME  = 'CAMERA  '   / camera name
# HIERARCH ESO INS OPTI9 NAME  = 'free    '   / element name in wheel 4 (interfere
# HIERARCH ESO INS OPTI10 NAME = 'free    '   / Element name in wheel 5 (interf. 2
# HIERARCH ESO INS OPTI2 ID    = '        '   / Id of long slit or polarimetric ma
# HIERARCH ESO INS OPTI3 ID    = '+6      '   / Identification of collimator
# HIERARCH ESO INS OPTI4 ID    = '        '   / Id of retarder plate
# HIERARCH ESO INS OPTI5 ID    = '        '   / element id in wheel 1 (Wollaston)
# HIERARCH ESO INS OPTI6 ID    = '        '   / element id in wheel2 (grism)
# HIERARCH ESO INS OPTI7 ID    = '+76     '   / element id in wheel3 (parallel bea
# HIERARCH ESO INS OPTI8 ID    = '+8      '   / camera id
# HIERARCH ESO INS OPTI9 ID    = '        '   / element id in wheel 4 (interferenc
# HIERARCH ESO INS OPTI10 ID   = '        '   / Element id in wheel 5 (interf. 2)
# HIERARCH ESO INS OPTI2 TYPE  = '        '   / Element type in the focal field.
# HIERARCH ESO INS OPTI3 TYPE  = 'COLL    '   / Element type
# HIERARCH ESO INS OPTI4 TYPE  = '        '   / Element type
# HIERARCH ESO INS OPTI5 TYPE  = '        '   / Element type in wheel 1
# HIERARCH ESO INS OPTI6 TYPE  = '        '   / Element type in wheel 2
# HIERARCH ESO INS OPTI7 TYPE  = 'FILT    '   / Element type in wheel 3
# HIERARCH ESO INS OPTI8 TYPE  = 'CAMERA  '   / Element type
# HIERARCH ESO INS OPTI9 TYPE  = '        '   / Element type in wheel 4
# HIERARCH ESO INS OPTI10 TYPE = '        '   / Element type in wheel 5
# HIERARCH ESO DET CHIP1 INDEX =            1 / Chip index
# HIERARCH ESO DET CHIP1 ID    = 'CCID20-14-5-3' / Detector chip identification
# HIERARCH ESO DET CHIP1 NAME  = 'MIT/LL mosaic' / Detector chip name
# HIERARCH ESO DET CHIP1 DATE  = '2001-08-01' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP1 X     =            1 / X location in array
# HIERARCH ESO DET CHIP1 Y     =            2 / Y location in array
# HIERARCH ESO DET CHIP1 NX    =         4096 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY    =         2048 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX  =         15.0 / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY  =         15.0 / Size of pixel in Y
# HIERARCH ESO DET CHIP1 XGAP  =    30.000000 / Gap between chips along x
# HIERARCH ESO DET CHIP1 YGAP  =   480.000000 / Gap between chips along y
# HIERARCH ESO DET OUT1 INDEX  =            1 / Output index
# HIERARCH ESO DET OUT1 ID     = 'A       '   / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 NAME   = 'A       '   / Description of output
# HIERARCH ESO DET OUT1 CHIP   =            1 / index of chip it belongs to
# HIERARCH ESO DET OUT1 X      =            1 / X location of output
# HIERARCH ESO DET OUT1 Y      =         1024 / Y location of output
# HIERARCH ESO DET OUT1 NX     =         2048 / valid pixels along X
# HIERARCH ESO DET OUT1 NY     =         1024 / valid pixels along Y
# HIERARCH ESO DET OUT1 PRSCX  =            0 / Prescan region in X
# HIERARCH ESO DET OUT1 OVSCX  =            0 / Overscan region in X
# HIERARCH ESO DET OUT1 PRSCY  =            5 / Prescan region in Y
# HIERARCH ESO DET OUT1 OVSCY  =            5 / Overscan region in Y
# HIERARCH ESO DET OUT1 CONAD  =         1.25 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 RON    =         2.70 / [e-] Readout noise per output (ele
# HIERARCH ESO DET OUT1 GAIN   =         0.80 / Conversion from electrons to ADU
# HIERARCH ESO DET ID          = 'CCD FIERA - Rev: 238334' / Detector system Id
# HIERARCH ESO DET NAME        = 'ccdF - fors2' / Name of detector system
# HIERARCH ESO DET DATE        = '2008-05-12' / Installation date
# HIERARCH ESO DET DID         = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET BITS        =           16 / Bits per pixel readout
# HIERARCH ESO DET RA          = -445589.27727324 / Apparent -~~:~~:~~.~ RA at sta
# HIERARCH ESO DET DEC         = -445589.27727324 / Apparent -~~:~~:~~.~ DEC at st
# HIERARCH ESO DET CHIPS       =            1 / # of chips in detector array
# HIERARCH ESO DET OUTPUTS     =            1 / # of outputs
# HIERARCH ESO DET OUTREF      =            0 / reference output
# HIERARCH ESO DET WINDOWS     =            1 / # of windows readout
# HIERARCH ESO DET SOFW MODE   = 'Normal  '   / CCD sw operational mode
# HIERARCH ESO DET EXP NO      =         4451 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE    = 'Normal  '   / Exposure type
# HIERARCH ESO DET EXP RDTTIME =       12.741 / image readout time
# HIERARCH ESO DET EXP XFERTIM =       13.188 / image transfer time
# HIERARCH ESO DET WIN1 ST     =            T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX   =            1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY   =            1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 NX     =         2068 / # of pixels along X
# HIERARCH ESO DET WIN1 NY     =         2048 / # of pixels along Y
# HIERARCH ESO DET WIN1 BINX   =            2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY   =            2 / Binning factor along Y
# HIERARCH ESO DET WIN1 NDIT   =            1 / # of subintegrations
# HIERARCH ESO DET WIN1 UIT1   =    10.000000 / user defined subintegration time
# HIERARCH ESO DET WIN1 DIT1   =     9.999686 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM   =      10.1634 / Dark current time
# HIERARCH ESO DET READ MODE   = 'normal  '   / Readout method
# HIERARCH ESO DET READ SPEED  = '200Kpix/s'  / Readout speed
# HIERARCH ESO DET READ CLOCK  = '200Kps/2ports/low_gain' / Readout clock pattern
# HIERARCH ESO DET READ NFRAM  =            1 / Number of readouts buffered in sin
# HIERARCH ESO DET FRAM ID     =            1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE   = 'Normal  '   / Type of frame
# HIERARCH ESO DET SHUT TYPE   = 'Iris    '   / type of shutter
# HIERARCH ESO DET SHUT ID     = 'fors shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMOPEN =        0.193 / Time taken to open shutter
# HIERARCH ESO DET SHUT TMCLOS =        0.192 / Time taken to close shutter
# HIERARCH ESO DET TELE INT    =         60.0 / Interval between two successive te
# HIERARCH ESO DET TELE NO     =            4 / # of sources active
# HIERARCH ESO DET TLM1 NAME   = 'CCD T1  '   / Description of telemetry param.
# HIERARCH ESO DET TLM1 ID     = 'Red CCD Sensor1' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 START  =       150.00 / Telemetry value at read start
# HIERARCH ESO DET TLM1 END    =       150.00 / Telemetry value at read completion
# HIERARCH ESO DET TLM2 NAME   = 'CCD T2  '   / Description of telemetry param.
# HIERARCH ESO DET TLM2 ID     = 'Red CCD Sensor2' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 START  =       149.90 / Telemetry value at read start
# HIERARCH ESO DET TLM2 END    =       149.90 / Telemetry value at read completion
# HIERARCH ESO DET TLM3 NAME   = 'FBOX T  '   / Description of telemetry param.
# HIERARCH ESO DET TLM3 ID     = 'Red FIERA Temp' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 START  =       286.50 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END    =       286.50 / Telemetry value at read completion
# HIERARCH ESO DET TLM4 NAME   = 'Vacuum  '   / Description of telemetry param.
# HIERARCH ESO DET TLM4 ID     = 'Red Vacuum' / ID of telemetry sensor
# HIERARCH ESO DET TLM4 START  =         0.00 / Telemetry value at read start
# HIERARCH ESO DET TLM4 END    =         0.00 / Telemetry value at read completion
# HIERARCH ESO DET CHIP1 RGAP  =     0.082780 / Gap rotation between chips 1 and 2
# COMMENT FTU-2_5_2/2021-08-21T05:29:48/expFORS.ftt
# HISTORY FTU-2_5_2/2021-08-21/CHANGE: DET.CHIPS, 1
# HISTORY FTU-2_5_2/2021-08-21/CHANGE: DET.OUTPUTS, 1
# HISTORY FTU-2_5_2/2021-08-21/COPY: DET.OUT1.NY->DET.OUT1.Y, 1024
# HISTORY FTU-2_5_2/2021-08-21/REMOVE: CDELT1, 2.000000000
# HISTORY FTU-2_5_2/2021-08-21/REMOVE: CDELT2, 2.000000000
# HISTORY FTU-2_5_2/2021-08-21/REMOVE: PCOUNT, 0
# HISTORY FTU-2_5_2/2021-08-21/REMOVE: GCOUNT, 1
# ORIGFILE= 'FORS2_ACQ233.8.CHIP1.fits' / Original File Name
# ARCFILE = 'FORS2.2021-08-21T05:29:16.174.fits' / Archive File Name
# CHECKSUM= 'mAAan55XmAAam33W'   / HDU checksum updated 2021-08-21T05:29:49
# DATASUM = '2224014327'         / data unit checksum updated 2021-08-21T05:29:49
