# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/FORS2.2022-01-29T07_05_26.457/Spectra_extraction/redshift.txt")
z = 0.0238  
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.0238

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        29
# chi2/DOF: 0.003134; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        35
# chi2/DOF: 0.002019; DOF: 2013; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-18.81585487,  34.71986913])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        37
#  comp.  1:       -18        41
#  comp.  2:       -18        31
# chi2/DOF: 0.9330; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.118      0.12     -18    41
# Comp:  1                 Hbeta      4.637      0.12     -18    41
# Comp:  1                Halpha      16.15      0.12     -18    41
# Comp:  2             [SII]6716      1.773      0.11     -18    31
# Comp:  2             [SII]6731      1.772      0.11     -18    31
# Comp:  2              HeII4687      0.000      0.11     -18    31
# Comp:  2               HeI5876     0.4172      0.11     -18    31
# Comp:  2          [OIII]5007_d      3.919      0.14     -18    31
# Comp:  2            [OI]6300_d     0.3406      0.14     -18    31
# Comp:  2           [NII]6583_d      9.107      0.14     -18    31
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:   15.5; gas flux:      2 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  33.39; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  118.4; gas flux:     22 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  13.82; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  13.45; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.198; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:     22; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.903; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  53.03; gas flux:     13 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -18        40
#  comp.  2:       -15        31
# chi2/DOF: 0.9183; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.833      0.12     -18    40
# Comp:  1                 Hbeta      4.849      0.12     -18    40
# Comp:  1                Halpha      16.09      0.12     -18    40
# Comp:  2             [SII]6716      1.639      0.11     -15    31
# Comp:  2             [SII]6731      1.822      0.11     -15    31
# Comp:  2              HeII4687      0.000      0.11     -15    31
# Comp:  2               HeI5876     0.4484      0.11     -15    31
# Comp:  2          [OIII]5007_d      3.823      0.14     -15    31
# Comp:  2            [OI]6300_d     0.3221      0.14     -15    31
# Comp:  2           [NII]6583_d      9.119      0.14     -15    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        45
#  comp.  1:       -19        42
#  comp.  2:       -19        32
# chi2/DOF: 0.9124; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.663      0.12     -19    42
# Comp:  1                 Hbeta      4.593      0.12     -19    42
# Comp:  1                Halpha      16.41      0.12     -19    42
# Comp:  2             [SII]6716      1.874      0.11     -19    32
# Comp:  2             [SII]6731      1.540      0.11     -19    32
# Comp:  2              HeII4687     0.1733      0.11     -19    32
# Comp:  2               HeI5876     0.4245      0.11     -19    32
# Comp:  2          [OIII]5007_d      4.087      0.14     -19    32
# Comp:  2            [OI]6300_d     0.3290      0.14     -19    32
# Comp:  2           [NII]6583_d      9.052      0.14     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        21
#  comp.  1:       -19        41
#  comp.  2:       -18        33
# chi2/DOF: 0.9096; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.459      0.12     -19    41
# Comp:  1                 Hbeta      5.015      0.12     -19    41
# Comp:  1                Halpha      16.47      0.12     -19    41
# Comp:  2             [SII]6716      1.722      0.12     -18    33
# Comp:  2             [SII]6731      1.937      0.12     -18    33
# Comp:  2              HeII4687      0.000      0.12     -18    33
# Comp:  2               HeI5876     0.4568      0.12     -18    33
# Comp:  2          [OIII]5007_d      3.889      0.15     -18    33
# Comp:  2            [OI]6300_d     0.3082      0.15     -18    33
# Comp:  2           [NII]6583_d      9.147      0.15     -18    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        33
#  comp.  1:       -17        41
#  comp.  2:       -17        24
# chi2/DOF: 0.9094; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.091      0.12     -17    41
# Comp:  1                 Hbeta      4.625      0.12     -17    41
# Comp:  1                Halpha      16.22      0.12     -17    41
# Comp:  2             [SII]6716      1.657      0.11     -17    24
# Comp:  2             [SII]6731      1.980      0.11     -17    24
# Comp:  2              HeII4687      0.000      0.11     -17    24
# Comp:  2               HeI5876     0.4059      0.11     -17    24
# Comp:  2          [OIII]5007_d      3.857      0.14     -17    24
# Comp:  2            [OI]6300_d     0.3787      0.14     -17    24
# Comp:  2           [NII]6583_d      9.005      0.14     -17    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        56
#  comp.  1:       -17        40
#  comp.  2:       -18        34
# chi2/DOF: 0.9159; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.889      0.12     -17    40
# Comp:  1                 Hbeta      4.355      0.12     -17    40
# Comp:  1                Halpha      16.01      0.12     -17    40
# Comp:  2             [SII]6716      1.834      0.12     -18    34
# Comp:  2             [SII]6731      1.929      0.12     -18    34
# Comp:  2              HeII4687    0.03469      0.12     -18    34
# Comp:  2               HeI5876     0.4252      0.12     -18    34
# Comp:  2          [OIII]5007_d      3.812      0.15     -18    34
# Comp:  2            [OI]6300_d     0.3498      0.15     -18    34
# Comp:  2           [NII]6583_d      9.220      0.15     -18    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        46
#  comp.  1:       -19        39
#  comp.  2:       -19        27
# chi2/DOF: 0.9150; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.601      0.12     -19    39
# Comp:  1                 Hbeta      4.727      0.12     -19    39
# Comp:  1                Halpha      16.11      0.12     -19    39
# Comp:  2             [SII]6716      1.897      0.11     -19    27
# Comp:  2             [SII]6731      1.786      0.11     -19    27
# Comp:  2              HeII4687   0.004207      0.11     -19    27
# Comp:  2               HeI5876     0.4014      0.11     -19    27
# Comp:  2          [OIII]5007_d      3.650      0.14     -19    27
# Comp:  2            [OI]6300_d     0.3475      0.14     -19    27
# Comp:  2           [NII]6583_d      8.944      0.14     -19    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        45
#  comp.  1:       -16        42
#  comp.  2:       -18        30
# chi2/DOF: 0.9121; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.802      0.12     -16    42
# Comp:  1                 Hbeta      4.516      0.12     -16    42
# Comp:  1                Halpha      16.19      0.12     -16    42
# Comp:  2             [SII]6716      1.780      0.11     -18    30
# Comp:  2             [SII]6731      1.815      0.11     -18    30
# Comp:  2              HeII4687      0.000      0.11     -18    30
# Comp:  2               HeI5876     0.3824      0.11     -18    30
# Comp:  2          [OIII]5007_d      3.704      0.14     -18    30
# Comp:  2            [OI]6300_d     0.3169      0.14     -18    30
# Comp:  2           [NII]6583_d      9.079      0.14     -18    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        49
#  comp.  1:       -18        42
#  comp.  2:       -16        32
# chi2/DOF: 0.9242; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.546      0.12     -18    42
# Comp:  1                 Hbeta      4.808      0.12     -18    42
# Comp:  1                Halpha      16.23      0.12     -18    42
# Comp:  2             [SII]6716      1.723      0.11     -16    32
# Comp:  2             [SII]6731      1.768      0.11     -16    32
# Comp:  2              HeII4687      0.000      0.11     -16    32
# Comp:  2               HeI5876     0.4362      0.11     -16    32
# Comp:  2          [OIII]5007_d      3.750      0.14     -16    32
# Comp:  2            [OI]6300_d     0.3549      0.14     -16    32
# Comp:  2           [NII]6583_d      9.134      0.14     -16    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        47
#  comp.  1:       -19        39
#  comp.  2:       -17        33
# chi2/DOF: 0.9136; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.429      0.12     -19    39
# Comp:  1                 Hbeta      5.150      0.12     -19    39
# Comp:  1                Halpha      16.13      0.12     -19    39
# Comp:  2             [SII]6716      1.886      0.11     -17    33
# Comp:  2             [SII]6731      1.671      0.11     -17    33
# Comp:  2              HeII4687      0.000      0.11     -17    33
# Comp:  2               HeI5876     0.4023      0.11     -17    33
# Comp:  2          [OIII]5007_d      4.294      0.15     -17    33
# Comp:  2            [OI]6300_d     0.3700      0.15     -17    33
# Comp:  2           [NII]6583_d      9.182      0.15     -17    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        50
#  comp.  1:       -16        43
#  comp.  2:       -16        34
# chi2/DOF: 0.9002; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.607      0.12     -16    43
# Comp:  1                 Hbeta      4.674      0.12     -16    43
# Comp:  1                Halpha      16.32      0.12     -16    43
# Comp:  2             [SII]6716      1.778      0.12     -16    34
# Comp:  2             [SII]6731      2.052      0.12     -16    34
# Comp:  2              HeII4687      0.000      0.12     -16    34
# Comp:  2               HeI5876     0.3919      0.12     -16    34
# Comp:  2          [OIII]5007_d      4.294      0.15     -16    34
# Comp:  2            [OI]6300_d     0.3557      0.15     -16    34
# Comp:  2           [NII]6583_d      9.177      0.15     -16    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        30
#  comp.  1:       -17        40
#  comp.  2:       -18        35
# chi2/DOF: 0.9205; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.245      0.12     -17    40
# Comp:  1                 Hbeta      4.989      0.12     -17    40
# Comp:  1                Halpha      15.95      0.12     -17    40
# Comp:  2             [SII]6716      1.741      0.12     -18    35
# Comp:  2             [SII]6731      1.624      0.12     -18    35
# Comp:  2              HeII4687      0.000      0.12     -18    35
# Comp:  2               HeI5876     0.4385      0.12     -18    35
# Comp:  2          [OIII]5007_d      3.818      0.15     -18    35
# Comp:  2            [OI]6300_d     0.3759      0.15     -18    35
# Comp:  2           [NII]6583_d      9.279      0.15     -18    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        40
#  comp.  1:       -18        42
#  comp.  2:       -18        35
# chi2/DOF: 0.9166; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.636      0.12     -18    42
# Comp:  1                 Hbeta      4.492      0.12     -18    42
# Comp:  1                Halpha      16.28      0.12     -18    42
# Comp:  2             [SII]6716      1.690      0.12     -18    35
# Comp:  2             [SII]6731      1.588      0.12     -18    35
# Comp:  2              HeII4687      0.000      0.12     -18    35
# Comp:  2               HeI5876     0.4208      0.12     -18    35
# Comp:  2          [OIII]5007_d      4.265      0.15     -18    35
# Comp:  2            [OI]6300_d     0.3046      0.15     -18    35
# Comp:  2           [NII]6583_d      9.297      0.15     -18    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -17        41
#  comp.  2:       -17        31
# chi2/DOF: 0.9170; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.305      0.12     -17    41
# Comp:  1                 Hbeta      4.342      0.12     -17    41
# Comp:  1                Halpha      16.07      0.12     -17    41
# Comp:  2             [SII]6716      1.680      0.11     -17    31
# Comp:  2             [SII]6731      1.581      0.11     -17    31
# Comp:  2              HeII4687      0.000      0.11     -17    31
# Comp:  2               HeI5876     0.4408      0.11     -17    31
# Comp:  2          [OIII]5007_d      4.121      0.14     -17    31
# Comp:  2            [OI]6300_d     0.3408      0.14     -17    31
# Comp:  2           [NII]6583_d      9.101      0.14     -17    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        34
#  comp.  1:       -19        42
#  comp.  2:       -17        32
# chi2/DOF: 0.9065; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.440      0.12     -19    42
# Comp:  1                 Hbeta      5.138      0.12     -19    42
# Comp:  1                Halpha      16.43      0.12     -19    42
# Comp:  2             [SII]6716      1.730      0.11     -17    32
# Comp:  2             [SII]6731      1.581      0.11     -17    32
# Comp:  2              HeII4687     0.1940      0.11     -17    32
# Comp:  2               HeI5876     0.4751      0.11     -17    32
# Comp:  2          [OIII]5007_d      4.281      0.14     -17    32
# Comp:  2            [OI]6300_d     0.3585      0.14     -17    32
# Comp:  2           [NII]6583_d      9.200      0.14     -17    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        20
#  comp.  1:       -18        41
#  comp.  2:       -17        31
# chi2/DOF: 0.9130; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.838      0.12     -18    41
# Comp:  1                 Hbeta      4.307      0.12     -18    41
# Comp:  1                Halpha      16.17      0.12     -18    41
# Comp:  2             [SII]6716      1.831      0.11     -17    31
# Comp:  2             [SII]6731      1.877      0.11     -17    31
# Comp:  2              HeII4687    0.04377      0.11     -17    31
# Comp:  2               HeI5876     0.4077      0.11     -17    31
# Comp:  2          [OIII]5007_d      4.088      0.14     -17    31
# Comp:  2            [OI]6300_d     0.2952      0.14     -17    31
# Comp:  2           [NII]6583_d      9.139      0.14     -17    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        46
#  comp.  1:       -17        39
#  comp.  2:       -17        26
# chi2/DOF: 0.9219; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.403      0.12     -17    39
# Comp:  1                 Hbeta      4.798      0.12     -17    39
# Comp:  1                Halpha      16.06      0.12     -17    39
# Comp:  2             [SII]6716      1.643      0.11     -17    26
# Comp:  2             [SII]6731      1.845      0.11     -17    26
# Comp:  2              HeII4687      0.000      0.11     -17    26
# Comp:  2               HeI5876     0.4185      0.11     -17    26
# Comp:  2          [OIII]5007_d      3.890      0.14     -17    26
# Comp:  2            [OI]6300_d     0.3141      0.14     -17    26
# Comp:  2           [NII]6583_d      8.959      0.14     -17    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        33
#  comp.  1:       -18        42
#  comp.  2:       -18        31
# chi2/DOF: 0.9153; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.325      0.12     -18    42
# Comp:  1                 Hbeta      4.315      0.12     -18    42
# Comp:  1                Halpha      16.24      0.12     -18    42
# Comp:  2             [SII]6716      1.813      0.11     -18    31
# Comp:  2             [SII]6731      1.971      0.11     -18    31
# Comp:  2              HeII4687      0.000      0.11     -18    31
# Comp:  2               HeI5876     0.4109      0.11     -18    31
# Comp:  2          [OIII]5007_d      3.621      0.14     -18    31
# Comp:  2            [OI]6300_d     0.3459      0.14     -18    31
# Comp:  2           [NII]6583_d      9.116      0.14     -18    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        13
#  comp.  1:       -17        38
#  comp.  2:       -17        34
# chi2/DOF: 0.9113; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.092      0.12     -17    38
# Comp:  1                 Hbeta      5.123      0.12     -17    38
# Comp:  1                Halpha      16.02      0.12     -17    38
# Comp:  2             [SII]6716      1.870      0.12     -17    34
# Comp:  2             [SII]6731      1.654      0.12     -17    34
# Comp:  2              HeII4687     0.1731      0.12     -17    34
# Comp:  2               HeI5876     0.4644      0.12     -17    34
# Comp:  2          [OIII]5007_d      3.798      0.15     -17    34
# Comp:  2            [OI]6300_d     0.3772      0.15     -17    34
# Comp:  2           [NII]6583_d      9.280      0.15     -17    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        35
#  comp.  1:       -18        40
#  comp.  2:       -19        33
# chi2/DOF: 0.9202; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.133      0.12     -18    40
# Comp:  1                 Hbeta      4.541      0.12     -18    40
# Comp:  1                Halpha      16.10      0.12     -18    40
# Comp:  2             [SII]6716      1.931      0.11     -19    33
# Comp:  2             [SII]6731      1.917      0.11     -19    33
# Comp:  2              HeII4687      0.000      0.11     -19    33
# Comp:  2               HeI5876     0.4358      0.11     -19    33
# Comp:  2          [OIII]5007_d      3.692      0.15     -19    33
# Comp:  2            [OI]6300_d     0.3214      0.15     -19    33
# Comp:  2           [NII]6583_d      9.123      0.15     -19    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        27
#  comp.  1:       -18        41
#  comp.  2:       -16        24
# chi2/DOF: 0.9165; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.506      0.12     -18    41
# Comp:  1                 Hbeta      4.225      0.12     -18    41
# Comp:  1                Halpha      16.18      0.12     -18    41
# Comp:  2             [SII]6716      1.579      0.11     -16    24
# Comp:  2             [SII]6731      1.827      0.11     -16    24
# Comp:  2              HeII4687      0.000      0.11     -16    24
# Comp:  2               HeI5876     0.4247      0.11     -16    24
# Comp:  2          [OIII]5007_d      4.028      0.14     -16    24
# Comp:  2            [OI]6300_d     0.3448      0.14     -16    24
# Comp:  2           [NII]6583_d      8.954      0.14     -16    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        25
#  comp.  1:       -19        41
#  comp.  2:       -19        32
# chi2/DOF: 0.9191; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.511      0.12     -19    41
# Comp:  1                 Hbeta      4.827      0.12     -19    41
# Comp:  1                Halpha      16.43      0.12     -19    41
# Comp:  2             [SII]6716      1.645      0.11     -19    32
# Comp:  2             [SII]6731      1.822      0.11     -19    32
# Comp:  2              HeII4687    0.04162      0.11     -19    32
# Comp:  2               HeI5876     0.4638      0.11     -19    32
# Comp:  2          [OIII]5007_d      4.030      0.14     -19    32
# Comp:  2            [OI]6300_d     0.3474      0.14     -19    32
# Comp:  2           [NII]6583_d      9.127      0.14     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        42
#  comp.  1:       -19        40
#  comp.  2:       -17        30
# chi2/DOF: 0.9177; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.938      0.12     -19    40
# Comp:  1                 Hbeta      4.841      0.12     -19    40
# Comp:  1                Halpha      16.12      0.12     -19    40
# Comp:  2             [SII]6716      1.917      0.11     -17    30
# Comp:  2             [SII]6731      1.631      0.11     -17    30
# Comp:  2              HeII4687    0.01217      0.11     -17    30
# Comp:  2               HeI5876     0.4240      0.11     -17    30
# Comp:  2          [OIII]5007_d      4.232      0.14     -17    30
# Comp:  2            [OI]6300_d     0.3506      0.14     -17    30
# Comp:  2           [NII]6583_d      9.161      0.14     -17    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        37
#  comp.  1:       -19        39
#  comp.  2:       -19        31
# chi2/DOF: 0.9164; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.145      0.12     -19    39
# Comp:  1                 Hbeta      4.250      0.12     -19    39
# Comp:  1                Halpha      16.03      0.12     -19    39
# Comp:  2             [SII]6716      1.802      0.11     -19    31
# Comp:  2             [SII]6731      1.719      0.11     -19    31
# Comp:  2              HeII4687     0.1484      0.11     -19    31
# Comp:  2               HeI5876     0.4019      0.11     -19    31
# Comp:  2          [OIII]5007_d      3.577      0.14     -19    31
# Comp:  2            [OI]6300_d     0.2928      0.14     -19    31
# Comp:  2           [NII]6583_d      9.107      0.14     -19    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        28
#  comp.  1:       -19        40
#  comp.  2:       -18        28
# chi2/DOF: 0.9096; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.425      0.12     -19    40
# Comp:  1                 Hbeta      4.314      0.12     -19    40
# Comp:  1                Halpha      16.21      0.12     -19    40
# Comp:  2             [SII]6716      1.954      0.11     -18    28
# Comp:  2             [SII]6731      1.581      0.11     -18    28
# Comp:  2              HeII4687    0.01648      0.11     -18    28
# Comp:  2               HeI5876     0.4348      0.11     -18    28
# Comp:  2          [OIII]5007_d      3.987      0.14     -18    28
# Comp:  2            [OI]6300_d     0.3020      0.14     -18    28
# Comp:  2           [NII]6583_d      9.087      0.14     -18    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        33
#  comp.  1:       -17        39
#  comp.  2:       -19        31
# chi2/DOF: 0.9214; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.157      0.12     -17    39
# Comp:  1                 Hbeta      4.489      0.12     -17    39
# Comp:  1                Halpha      16.08      0.12     -17    39
# Comp:  2             [SII]6716      1.894      0.11     -19    31
# Comp:  2             [SII]6731      1.851      0.11     -19    31
# Comp:  2              HeII4687    0.03042      0.11     -19    31
# Comp:  2               HeI5876     0.4543      0.11     -19    31
# Comp:  2          [OIII]5007_d      3.888      0.14     -19    31
# Comp:  2            [OI]6300_d     0.3516      0.14     -19    31
# Comp:  2           [NII]6583_d      9.010      0.14     -19    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -16        41
#  comp.  2:       -16        31
# chi2/DOF: 0.9160; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.220      0.12     -16    41
# Comp:  1                 Hbeta      4.572      0.12     -16    41
# Comp:  1                Halpha      16.02      0.12     -16    41
# Comp:  2             [SII]6716      1.796      0.11     -16    31
# Comp:  2             [SII]6731      1.773      0.11     -16    31
# Comp:  2              HeII4687    0.02143      0.11     -16    31
# Comp:  2               HeI5876     0.4060      0.11     -16    31
# Comp:  2          [OIII]5007_d      4.241      0.14     -16    31
# Comp:  2            [OI]6300_d     0.3256      0.14     -16    31
# Comp:  2           [NII]6583_d      9.078      0.14     -16    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        13
#  comp.  1:       -17        40
#  comp.  2:       -16        27
# chi2/DOF: 0.9124; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.970      0.12     -17    40
# Comp:  1                 Hbeta      4.477      0.12     -17    40
# Comp:  1                Halpha      16.12      0.12     -17    40
# Comp:  2             [SII]6716      1.672      0.11     -16    27
# Comp:  2             [SII]6731      1.678      0.11     -16    27
# Comp:  2              HeII4687    0.04915      0.11     -16    27
# Comp:  2               HeI5876     0.3873      0.11     -16    27
# Comp:  2          [OIII]5007_d      3.943      0.14     -16    27
# Comp:  2            [OI]6300_d     0.3165      0.14     -16    27
# Comp:  2           [NII]6583_d      8.956      0.14     -16    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:       -18        41
#  comp.  2:       -17        32
# chi2/DOF: 0.9219; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.005      0.12     -18    41
# Comp:  1                 Hbeta      4.807      0.12     -18    41
# Comp:  1                Halpha      16.06      0.12     -18    41
# Comp:  2             [SII]6716      1.745      0.11     -17    32
# Comp:  2             [SII]6731      1.723      0.11     -17    32
# Comp:  2              HeII4687      0.000      0.11     -17    32
# Comp:  2               HeI5876     0.4068      0.11     -17    32
# Comp:  2          [OIII]5007_d      4.151      0.14     -17    32
# Comp:  2            [OI]6300_d     0.3443      0.14     -17    32
# Comp:  2           [NII]6583_d      9.061      0.14     -17    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        31
#  comp.  1:       -18        38
#  comp.  2:       -17        33
# chi2/DOF: 0.9201; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.172      0.12     -18    38
# Comp:  1                 Hbeta      4.429      0.12     -18    38
# Comp:  1                Halpha      15.85      0.12     -18    38
# Comp:  2             [SII]6716      1.842      0.12     -17    33
# Comp:  2             [SII]6731      2.042      0.12     -17    33
# Comp:  2              HeII4687      0.000      0.12     -17    33
# Comp:  2               HeI5876     0.4706      0.12     -17    33
# Comp:  2          [OIII]5007_d      4.188      0.15     -17    33
# Comp:  2            [OI]6300_d     0.3715      0.15     -17    33
# Comp:  2           [NII]6583_d      9.285      0.15     -17    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        38
#  comp.  1:       -16        40
#  comp.  2:       -16        27
# chi2/DOF: 0.9178; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.827      0.12     -16    40
# Comp:  1                 Hbeta      4.990      0.12     -16    40
# Comp:  1                Halpha      16.07      0.12     -16    40
# Comp:  2             [SII]6716      1.794      0.11     -16    27
# Comp:  2             [SII]6731      1.476      0.11     -16    27
# Comp:  2              HeII4687    0.04546      0.11     -16    27
# Comp:  2               HeI5876     0.4193      0.11     -16    27
# Comp:  2          [OIII]5007_d      3.669      0.14     -16    27
# Comp:  2            [OI]6300_d     0.2951      0.14     -16    27
# Comp:  2           [NII]6583_d      8.953      0.14     -16    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        42
#  comp.  1:       -16        40
#  comp.  2:       -16        29
# chi2/DOF: 0.9166; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.208      0.12     -16    40
# Comp:  1                 Hbeta      5.197      0.12     -16    40
# Comp:  1                Halpha      16.05      0.12     -16    40
# Comp:  2             [SII]6716      1.612      0.11     -16    29
# Comp:  2             [SII]6731      1.855      0.11     -16    29
# Comp:  2              HeII4687     0.2003      0.11     -16    29
# Comp:  2               HeI5876     0.4544      0.11     -16    29
# Comp:  2          [OIII]5007_d      4.174      0.14     -16    29
# Comp:  2            [OI]6300_d     0.3244      0.14     -16    29
# Comp:  2           [NII]6583_d      9.041      0.14     -16    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        13
#  comp.  1:       -18        42
#  comp.  2:       -18        36
# chi2/DOF: 0.9191; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.422      0.12     -18    42
# Comp:  1                 Hbeta      4.504      0.12     -18    42
# Comp:  1                Halpha      16.26      0.12     -18    42
# Comp:  2             [SII]6716      1.772      0.12     -18    36
# Comp:  2             [SII]6731      1.990      0.12     -18    36
# Comp:  2              HeII4687    0.01192      0.12     -18    36
# Comp:  2               HeI5876     0.4277      0.12     -18    36
# Comp:  2          [OIII]5007_d      3.906      0.15     -18    36
# Comp:  2            [OI]6300_d     0.3702      0.15     -18    36
# Comp:  2           [NII]6583_d      9.250      0.15     -18    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:       -17        41
#  comp.  2:       -20        36
# chi2/DOF: 0.9025; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.594      0.12     -17    41
# Comp:  1                 Hbeta      5.323      0.12     -17    41
# Comp:  1                Halpha      16.33      0.12     -17    41
# Comp:  2             [SII]6716      1.856      0.12     -20    36
# Comp:  2             [SII]6731      1.903      0.12     -20    36
# Comp:  2              HeII4687     0.1514      0.12     -20    36
# Comp:  2               HeI5876     0.3969      0.12     -20    36
# Comp:  2          [OIII]5007_d      3.669      0.15     -20    36
# Comp:  2            [OI]6300_d     0.3200      0.15     -20    36
# Comp:  2           [NII]6583_d      9.309      0.15     -20    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        46
#  comp.  1:       -17        41
#  comp.  2:       -16        27
# chi2/DOF: 0.9076; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.483      0.12     -17    41
# Comp:  1                 Hbeta      4.804      0.12     -17    41
# Comp:  1                Halpha      16.03      0.12     -17    41
# Comp:  2             [SII]6716      1.628      0.11     -16    27
# Comp:  2             [SII]6731      1.970      0.11     -16    27
# Comp:  2              HeII4687     0.2078      0.11     -16    27
# Comp:  2               HeI5876     0.4142      0.11     -16    27
# Comp:  2          [OIII]5007_d      3.926      0.14     -16    27
# Comp:  2            [OI]6300_d     0.3282      0.14     -16    27
# Comp:  2           [NII]6583_d      9.006      0.14     -16    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        23
#  comp.  1:       -17        42
#  comp.  2:       -18        35
# chi2/DOF: 0.9178; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.589      0.12     -17    42
# Comp:  1                 Hbeta      5.182      0.12     -17    42
# Comp:  1                Halpha      16.43      0.12     -17    42
# Comp:  2             [SII]6716      1.949      0.12     -18    35
# Comp:  2             [SII]6731      1.898      0.12     -18    35
# Comp:  2              HeII4687      0.000      0.12     -18    35
# Comp:  2               HeI5876     0.4508      0.12     -18    35
# Comp:  2          [OIII]5007_d      3.961      0.15     -18    35
# Comp:  2            [OI]6300_d     0.3479      0.15     -18    35
# Comp:  2           [NII]6583_d      9.168      0.15     -18    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         5
#  comp.  1:       -17        41
#  comp.  2:       -19        29
# chi2/DOF: 0.9148; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.553      0.12     -17    41
# Comp:  1                 Hbeta      4.360      0.12     -17    41
# Comp:  1                Halpha      16.22      0.12     -17    41
# Comp:  2             [SII]6716      1.902      0.11     -19    29
# Comp:  2             [SII]6731      1.635      0.11     -19    29
# Comp:  2              HeII4687   0.009150      0.11     -19    29
# Comp:  2               HeI5876     0.4103      0.11     -19    29
# Comp:  2          [OIII]5007_d      4.078      0.14     -19    29
# Comp:  2            [OI]6300_d     0.3010      0.14     -19    29
# Comp:  2           [NII]6583_d      9.033      0.14     -19    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        49
#  comp.  1:       -19        38
#  comp.  2:       -16        28
# chi2/DOF: 0.9058; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.478      0.12     -19    38
# Comp:  1                 Hbeta      4.596      0.12     -19    38
# Comp:  1                Halpha      15.93      0.12     -19    38
# Comp:  2             [SII]6716      1.927      0.11     -16    28
# Comp:  2             [SII]6731      1.958      0.11     -16    28
# Comp:  2              HeII4687    0.04862      0.11     -16    28
# Comp:  2               HeI5876     0.4290      0.11     -16    28
# Comp:  2          [OIII]5007_d      4.117      0.14     -16    28
# Comp:  2            [OI]6300_d     0.3130      0.14     -16    28
# Comp:  2           [NII]6583_d      9.007      0.14     -16    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        53
#  comp.  1:       -18        42
#  comp.  2:       -19        32
# chi2/DOF: 0.9142; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.303      0.12     -18    42
# Comp:  1                 Hbeta      4.346      0.12     -18    42
# Comp:  1                Halpha      16.36      0.12     -18    42
# Comp:  2             [SII]6716      1.685      0.11     -19    32
# Comp:  2             [SII]6731      2.015      0.11     -19    32
# Comp:  2              HeII4687      0.000      0.11     -19    32
# Comp:  2               HeI5876     0.4237      0.11     -19    32
# Comp:  2          [OIII]5007_d      4.029      0.14     -19    32
# Comp:  2            [OI]6300_d     0.3044      0.14     -19    32
# Comp:  2           [NII]6583_d      9.028      0.14     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        22
#  comp.  1:       -18        41
#  comp.  2:       -16        30
# chi2/DOF: 0.9120; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.288      0.12     -18    41
# Comp:  1                 Hbeta      4.788      0.12     -18    41
# Comp:  1                Halpha      16.36      0.12     -18    41
# Comp:  2             [SII]6716      1.785      0.11     -16    30
# Comp:  2             [SII]6731      1.709      0.11     -16    30
# Comp:  2              HeII4687     0.1626      0.11     -16    30
# Comp:  2               HeI5876     0.4366      0.11     -16    30
# Comp:  2          [OIII]5007_d      3.765      0.14     -16    30
# Comp:  2            [OI]6300_d     0.3574      0.14     -16    30
# Comp:  2           [NII]6583_d      9.015      0.14     -16    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        48
#  comp.  1:       -18        42
#  comp.  2:       -18        31
# chi2/DOF: 0.9169; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      9.300      0.15     -18    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        50
#  comp.  1:       -19        42
#  comp.  2:       -18        38
# chi2/DOF: 0.9127; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.468      0.12     -19    42
# Comp:  1                 Hbeta      4.370      0.12     -19    42
# Comp:  1                Halpha      16.22      0.12     -19    42
# Comp:  2             [SII]6716      1.823      0.12     -18    38
# Comp:  2             [SII]6731      2.009      0.12     -18    38
# Comp:  2              HeII4687   0.007667      0.12     -18    38
# Comp:  2               HeI5876     0.4211      0.12     -18    38
# Comp:  2          [OIII]5007_d      3.806      0.15     -18    38
# Comp:  2            [OI]6300_d     0.3434      0.15     -18    38
# Comp:  2           [NII]6583_d      9.351      0.15     -18    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:       -17        42
#  comp.  2:       -20        33
# chi2/DOF: 0.9113; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.966      0.12     -17    42
# Comp:  1                 Hbeta      4.491      0.12     -17    42
# Comp:  1                Halpha      16.32      0.12     -17    42
# Comp:  2             [SII]6716      1.727      0.12     -20    33
# Comp:  2             [SII]6731      1.796      0.12     -20    33
# Comp:  2              HeII4687     0.1751      0.12     -20    33
# Comp:  2               HeI5876     0.4725      0.12     -20    33
# Comp:  2          [OIII]5007_d      3.741      0.15     -20    33
# Comp:  2            [OI]6300_d     0.3298      0.15     -20    33
# Comp:  2           [NII]6583_d      9.095      0.15     -20    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        43
#  comp.  1:       -17        42
#  comp.  2:       -17        29
# chi2/DOF: 0.9177; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.545      0.12     -17    42
# Comp:  1                 Hbeta      4.753      0.12     -17    42
# Comp:  1                Halpha      16.24      0.12     -17    42
# Comp:  2             [SII]6716      1.759      0.11     -17    29
# Comp:  2             [SII]6731      1.911      0.11     -17    29
# Comp:  2              HeII4687    0.01005      0.11     -17    29
# Comp:  2               HeI5876     0.3904      0.11     -17    29
# Comp:  2          [OIII]5007_d      3.855      0.14     -17    29
# Comp:  2            [OI]6300_d     0.3332      0.14     -17    29
# Comp:  2           [NII]6583_d      9.051      0.14     -17    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        49
#  comp.  1:       -18        42
#  comp.  2:       -18        35
# chi2/DOF: 0.9200; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.528      0.12     -18    42
# Comp:  1                 Hbeta      4.500      0.12     -18    42
# Comp:  1                Halpha      16.29      0.12     -18    42
# Comp:  2             [SII]6716      1.711      0.12     -18    35
# Comp:  2             [SII]6731      1.810      0.12     -18    35
# Comp:  2              HeII4687    0.05688      0.12     -18    35
# Comp:  2               HeI5876     0.4383      0.12     -18    35
# Comp:  2          [OIII]5007_d      3.771      0.15     -18    35
# Comp:  2            [OI]6300_d     0.2991      0.15     -18    35
# Comp:  2           [NII]6583_d      9.228      0.15     -18    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        49
#  comp.  1:       -17        40
#  comp.  2:       -18        34
# chi2/DOF: 0.9160; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.938      0.12     -17    40
# Comp:  1                 Hbeta      4.653      0.12     -17    40
# Comp:  1                Halpha      16.11      0.12     -17    40
# Comp:  2             [SII]6716      1.840      0.12     -18    34
# Comp:  2             [SII]6731      1.782      0.12     -18    34
# Comp:  2              HeII4687   0.002318      0.12     -18    34
# Comp:  2               HeI5876     0.4112      0.12     -18    34
# Comp:  2          [OIII]5007_d      3.741      0.15     -18    34
# Comp:  2            [OI]6300_d     0.3920      0.15     -18    34
# Comp:  2           [NII]6583_d      9.206      0.15     -18    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -18        39
#  comp.  2:       -19        32
# chi2/DOF: 0.9081; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.747      0.12     -18    39
# Comp:  1                 Hbeta      4.208      0.12     -18    39
# Comp:  1                Halpha      16.16      0.12     -18    39
# Comp:  2             [SII]6716      1.736      0.11     -19    32
# Comp:  2             [SII]6731      1.684      0.11     -19    32
# Comp:  2              HeII4687      0.000      0.11     -19    32
# Comp:  2               HeI5876     0.4005      0.11     -19    32
# Comp:  2          [OIII]5007_d      4.039      0.14     -19    32
# Comp:  2            [OI]6300_d     0.3663      0.14     -19    32
# Comp:  2           [NII]6583_d      9.128      0.14     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        46
#  comp.  1:       -18        43
#  comp.  2:       -17        29
# chi2/DOF: 0.9109; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.114      0.12     -18    43
# Comp:  1                 Hbeta      5.249      0.12     -18    43
# Comp:  1                Halpha      16.53      0.12     -18    43
# Comp:  2             [SII]6716      1.889      0.11     -17    29
# Comp:  2             [SII]6731      1.784      0.11     -17    29
# Comp:  2              HeII4687      0.000      0.11     -17    29
# Comp:  2               HeI5876     0.4321      0.11     -17    29
# Comp:  2          [OIII]5007_d      4.126      0.14     -17    29
# Comp:  2            [OI]6300_d     0.3846      0.14     -17    29
# Comp:  2           [NII]6583_d      9.026      0.14     -17    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -17        43
#  comp.  2:       -17        28
# chi2/DOF: 0.9119; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.968      0.12     -17    43
# Comp:  1                 Hbeta      4.805      0.12     -17    43
# Comp:  1                Halpha      16.62      0.12     -17    43
# Comp:  2             [SII]6716      1.881      0.11     -17    28
# Comp:  2             [SII]6731      1.548      0.11     -17    28
# Comp:  2              HeII4687    0.02064      0.11     -17    28
# Comp:  2               HeI5876     0.3968      0.11     -17    28
# Comp:  2          [OIII]5007_d      3.584      0.14     -17    28
# Comp:  2            [OI]6300_d     0.3384      0.14     -17    28
# Comp:  2           [NII]6583_d      9.051      0.14     -17    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        20
#  comp.  1:       -18        42
#  comp.  2:       -19        33
# chi2/DOF: 0.8970; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.895      0.12     -18    42
# Comp:  1                 Hbeta      4.361      0.12     -18    42
# Comp:  1                Halpha      16.13      0.12     -18    42
# Comp:  2             [SII]6716      1.830      0.12     -19    33
# Comp:  2             [SII]6731      1.976      0.12     -19    33
# Comp:  2              HeII4687      0.000      0.12     -19    33
# Comp:  2               HeI5876     0.4100      0.12     -19    33
# Comp:  2          [OIII]5007_d      3.678      0.15     -19    33
# Comp:  2            [OI]6300_d     0.3352      0.15     -19    33
# Comp:  2           [NII]6583_d      9.193      0.15     -19    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        31
#  comp.  1:       -19        42
#  comp.  2:       -18        28
# chi2/DOF: 0.9189; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.175      0.12     -19    42
# Comp:  1                 Hbeta      4.693      0.12     -19    42
# Comp:  1                Halpha      16.36      0.12     -19    42
# Comp:  2             [SII]6716      1.803      0.11     -18    28
# Comp:  2             [SII]6731      1.808      0.11     -18    28
# Comp:  2              HeII4687      0.000      0.11     -18    28
# Comp:  2               HeI5876     0.4452      0.11     -18    28
# Comp:  2          [OIII]5007_d      3.980      0.14     -18    28
# Comp:  2            [OI]6300_d     0.3246      0.14     -18    28
# Comp:  2           [NII]6583_d      9.035      0.14     -18    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        50
#  comp.  1:       -18        44
#  comp.  2:       -16        30
# chi2/DOF: 0.9212; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.194      0.12     -18    44
# Comp:  1                 Hbeta      4.804      0.12     -18    44
# Comp:  1                Halpha      16.37      0.12     -18    44
# Comp:  2             [SII]6716      1.823      0.11     -16    30
# Comp:  2             [SII]6731      1.810      0.11     -16    30
# Comp:  2              HeII4687      0.000      0.11     -16    30
# Comp:  2               HeI5876     0.3953      0.11     -16    30
# Comp:  2          [OIII]5007_d      4.161      0.14     -16    30
# Comp:  2            [OI]6300_d     0.3943      0.14     -16    30
# Comp:  2           [NII]6583_d      9.151      0.14     -16    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        36
#  comp.  1:       -17        39
#  comp.  2:       -17        35
# chi2/DOF: 0.9139; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.214      0.12     -17    39
# Comp:  1                 Hbeta      5.035      0.12     -17    39
# Comp:  1                Halpha      16.09      0.12     -17    39
# Comp:  2             [SII]6716      1.941      0.12     -17    35
# Comp:  2             [SII]6731      1.808      0.12     -17    35
# Comp:  2              HeII4687     0.1749      0.12     -17    35
# Comp:  2               HeI5876     0.4440      0.12     -17    35
# Comp:  2          [OIII]5007_d      3.875      0.15     -17    35
# Comp:  2            [OI]6300_d     0.3840      0.15     -17    35
# Comp:  2           [NII]6583_d      9.214      0.15     -17    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -17        40
#  comp.  2:       -18        27
# chi2/DOF: 0.9021; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.409      0.12     -17    40
# Comp:  1                 Hbeta      4.254      0.12     -17    40
# Comp:  1                Halpha      16.05      0.12     -17    40
# Comp:  2             [SII]6716      1.787      0.11     -18    27
# Comp:  2             [SII]6731      1.697      0.11     -18    27
# Comp:  2              HeII4687     0.1948      0.11     -18    27
# Comp:  2               HeI5876     0.3934      0.11     -18    27
# Comp:  2          [OIII]5007_d      3.901      0.14     -18    27
# Comp:  2            [OI]6300_d     0.2843      0.14     -18    27
# Comp:  2           [NII]6583_d      9.024      0.14     -18    27
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
