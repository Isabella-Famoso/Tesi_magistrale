# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_2.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/FORS2.2022-01-29T07_05_26.457/Spectra_extraction/redshift.txt") 
z = 0.0238 
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4200.76186755 4202.20746239 4203.65305724 ... 6928.59933581 6930.04493065
#  6931.49052549] [1.13698248 0.49337978 0.43880963 ... 0.31550322 0.34850406 0.33323623] [0.0440234 0.0440234 0.0440234 ... 0.0440234 0.0440234 0.0440234]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
# chi2/DOF: 0.01457; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
# chi2/DOF: 0.008863; DOF: 2013; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-67.07405756,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -246       602
#  comp.  1:       -37        34
#  comp.  2:       -36        40
# chi2/DOF: 1.905; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.39      0.22     -37    34
# Comp:  1                 Hbeta      34.93      0.22     -37    34
# Comp:  1                Halpha      118.6      0.22     -37    34
# Comp:  2             [SII]6716      13.27      0.22     -36    40
# Comp:  2             [SII]6731      11.12      0.22     -36    40
# Comp:  2              HeII4687     0.5237      0.22     -36    40
# Comp:  2               HeI5876      4.195      0.22     -36    40
# Comp:  2          [OIII]5007_d      47.25      0.28     -36    40
# Comp:  2            [OI]6300_d      1.987      0.28     -36    40
# Comp:  2           [NII]6583_d      38.83      0.28     -36    40
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  48.26; gas flux:     13 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  124.2; gas flux:     35 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  414.8; gas flux:    162 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  44.48; gas flux:     19 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  38.13; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.679; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  13.29; gas flux:      5 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  116.7; gas flux:     49 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.114; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   99.4; gas flux:     53 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -83       698
#  comp.  1:       -37        35
#  comp.  2:       -35        47
# chi2/DOF: 1.821; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.08      0.22     -37    35
# Comp:  1                 Hbeta      36.69      0.22     -37    35
# Comp:  1                Halpha      118.9      0.22     -37    35
# Comp:  2             [SII]6716      13.56      0.23     -35    47
# Comp:  2             [SII]6731      11.49      0.23     -35    47
# Comp:  2              HeII4687     0.4817      0.23     -35    47
# Comp:  2               HeI5876      4.410      0.23     -35    47
# Comp:  2          [OIII]5007_d      48.94      0.29     -35    47
# Comp:  2            [OI]6300_d      2.099      0.29     -35    47
# Comp:  2           [NII]6583_d      38.62      0.29     -35    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -400       745
#  comp.  1:       -39        39
#  comp.  2:       -35        34
# chi2/DOF: 1.728; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.27      0.22     -39    39
# Comp:  1                 Hbeta      35.27      0.22     -39    39
# Comp:  1                Halpha      121.1      0.22     -39    39
# Comp:  2             [SII]6716      13.10      0.22     -35    34
# Comp:  2             [SII]6731      10.20      0.22     -35    34
# Comp:  2              HeII4687     0.5482      0.22     -35    34
# Comp:  2               HeI5876      4.344      0.22     -35    34
# Comp:  2          [OIII]5007_d      47.16      0.28     -35    34
# Comp:  2            [OI]6300_d      1.882      0.28     -35    34
# Comp:  2           [NII]6583_d      38.00      0.28     -35    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -283       591
#  comp.  1:       -37        30
#  comp.  2:       -33        40
# chi2/DOF: 1.761; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.27      0.22     -37    30
# Comp:  1                 Hbeta      34.67      0.22     -37    30
# Comp:  1                Halpha      119.5      0.22     -37    30
# Comp:  2             [SII]6716      12.64      0.22     -33    40
# Comp:  2             [SII]6731      11.86      0.22     -33    40
# Comp:  2              HeII4687     0.5299      0.22     -33    40
# Comp:  2               HeI5876      4.567      0.22     -33    40
# Comp:  2          [OIII]5007_d      46.90      0.28     -33    40
# Comp:  2            [OI]6300_d      2.188      0.28     -33    40
# Comp:  2           [NII]6583_d      38.26      0.28     -33    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -176       461
#  comp.  1:       -38        38
#  comp.  2:       -35        32
# chi2/DOF: 1.719; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.48      0.22     -38    38
# Comp:  1                 Hbeta      35.88      0.22     -38    38
# Comp:  1                Halpha      118.1      0.22     -38    38
# Comp:  2             [SII]6716      12.64      0.22     -35    32
# Comp:  2             [SII]6731      11.64      0.22     -35    32
# Comp:  2              HeII4687     0.3686      0.22     -35    32
# Comp:  2               HeI5876      4.112      0.22     -35    32
# Comp:  2          [OIII]5007_d      45.93      0.28     -35    32
# Comp:  2            [OI]6300_d      2.082      0.28     -35    32
# Comp:  2           [NII]6583_d      36.72      0.28     -35    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -472       680
#  comp.  1:       -36        37
#  comp.  2:       -36        47
# chi2/DOF: 1.797; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.28      0.22     -36    37
# Comp:  1                 Hbeta      33.49      0.22     -36    37
# Comp:  1                Halpha      119.8      0.22     -36    37
# Comp:  2             [SII]6716      13.65      0.23     -36    47
# Comp:  2             [SII]6731      11.71      0.23     -36    47
# Comp:  2              HeII4687     0.5408      0.23     -36    47
# Comp:  2               HeI5876      4.117      0.23     -36    47
# Comp:  2          [OIII]5007_d      48.18      0.29     -36    47
# Comp:  2            [OI]6300_d      2.023      0.29     -36    47
# Comp:  2           [NII]6583_d      39.60      0.29     -36    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -168         1
#  comp.  1:       -38        32
#  comp.  2:       -38        28
# chi2/DOF: 1.751; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.57      0.22     -38    32
# Comp:  1                 Hbeta      35.32      0.22     -38    32
# Comp:  1                Halpha      118.3      0.22     -38    32
# Comp:  2             [SII]6716      13.35      0.22     -38    28
# Comp:  2             [SII]6731      10.65      0.22     -38    28
# Comp:  2              HeII4687     0.4434      0.22     -38    28
# Comp:  2               HeI5876      3.959      0.22     -38    28
# Comp:  2          [OIII]5007_d      43.61      0.27     -38    28
# Comp:  2            [OI]6300_d      1.831      0.27     -38    28
# Comp:  2           [NII]6583_d      37.66      0.27     -38    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -450       930
#  comp.  1:       -36        34
#  comp.  2:       -39        36
# chi2/DOF: 1.684; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.33      0.22     -36    34
# Comp:  1                 Hbeta      33.22      0.22     -36    34
# Comp:  1                Halpha      116.0      0.22     -36    34
# Comp:  2             [SII]6716      12.85      0.22     -39    36
# Comp:  2             [SII]6731      11.50      0.22     -39    36
# Comp:  2              HeII4687     0.3231      0.22     -39    36
# Comp:  2               HeI5876      3.753      0.22     -39    36
# Comp:  2          [OIII]5007_d      45.29      0.28     -39    36
# Comp:  2            [OI]6300_d      1.934      0.28     -39    36
# Comp:  2           [NII]6583_d      38.59      0.28     -39    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113       607
#  comp.  1:       -36        29
#  comp.  2:       -34        44
# chi2/DOF: 1.765; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.51      0.22     -36    29
# Comp:  1                 Hbeta      33.96      0.22     -36    29
# Comp:  1                Halpha      116.3      0.22     -36    29
# Comp:  2             [SII]6716      12.90      0.23     -34    44
# Comp:  2             [SII]6731      11.36      0.23     -34    44
# Comp:  2              HeII4687     0.5803      0.23     -34    44
# Comp:  2               HeI5876      4.436      0.23     -34    44
# Comp:  2          [OIII]5007_d      46.91      0.29     -34    44
# Comp:  2            [OI]6300_d      1.957      0.29     -34    44
# Comp:  2           [NII]6583_d      39.45      0.29     -34    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -215       264
#  comp.  1:       -37        29
#  comp.  2:       -33        42
# chi2/DOF: 1.634; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.68      0.22     -37    29
# Comp:  1                 Hbeta      38.61      0.22     -37    29
# Comp:  1                Halpha      119.1      0.22     -37    29
# Comp:  2             [SII]6716      13.51      0.23     -33    42
# Comp:  2             [SII]6731      11.07      0.23     -33    42
# Comp:  2              HeII4687     0.5352      0.23     -33    42
# Comp:  2               HeI5876      3.866      0.23     -33    42
# Comp:  2          [OIII]5007_d      49.03      0.28     -33    42
# Comp:  2            [OI]6300_d      2.010      0.28     -33    42
# Comp:  2           [NII]6583_d      38.96      0.28     -33    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -303      1000
#  comp.  1:       -36        31
#  comp.  2:       -30        40
# chi2/DOF: 1.660; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.30      0.22     -36    31
# Comp:  1                 Hbeta      32.03      0.22     -36    31
# Comp:  1                Halpha      116.9      0.22     -36    31
# Comp:  2             [SII]6716      13.60      0.22     -30    40
# Comp:  2             [SII]6731      12.00      0.22     -30    40
# Comp:  2              HeII4687     0.5628      0.22     -30    40
# Comp:  2               HeI5876      3.778      0.22     -30    40
# Comp:  2          [OIII]5007_d      49.80      0.28     -30    40
# Comp:  2            [OI]6300_d      1.940      0.28     -30    40
# Comp:  2           [NII]6583_d      38.40      0.28     -30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41       633
#  comp.  1:       -37        35
#  comp.  2:       -37        48
# chi2/DOF: 1.778; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.60      0.22     -37    35
# Comp:  1                 Hbeta      37.63      0.22     -37    35
# Comp:  1                Halpha      118.7      0.22     -37    35
# Comp:  2             [SII]6716      13.53      0.23     -37    48
# Comp:  2             [SII]6731      10.72      0.23     -37    48
# Comp:  2              HeII4687     0.4397      0.23     -37    48
# Comp:  2               HeI5876      4.394      0.23     -37    48
# Comp:  2          [OIII]5007_d      49.25      0.29     -37    48
# Comp:  2            [OI]6300_d      1.979      0.29     -37    48
# Comp:  2           [NII]6583_d      40.08      0.29     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -447       391
#  comp.  1:       -38        32
#  comp.  2:       -35        46
# chi2/DOF: 1.714; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.55      0.22     -38    32
# Comp:  1                 Hbeta      32.19      0.22     -38    32
# Comp:  1                Halpha      118.0      0.22     -38    32
# Comp:  2             [SII]6716      13.66      0.23     -35    46
# Comp:  2             [SII]6731      10.76      0.23     -35    46
# Comp:  2              HeII4687     0.6627      0.23     -35    46
# Comp:  2               HeI5876      4.509      0.23     -35    46
# Comp:  2          [OIII]5007_d      49.62      0.29     -35    46
# Comp:  2            [OI]6300_d      2.052      0.29     -35    46
# Comp:  2           [NII]6583_d      40.30      0.29     -35    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138      1000
#  comp.  1:       -38        39
#  comp.  2:       -33        42
# chi2/DOF: 1.689; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.80      0.22     -38    39
# Comp:  1                 Hbeta      33.38      0.22     -38    39
# Comp:  1                Halpha      118.1      0.22     -38    39
# Comp:  2             [SII]6716      12.61      0.23     -33    42
# Comp:  2             [SII]6731      10.59      0.23     -33    42
# Comp:  2              HeII4687     0.5036      0.23     -33    42
# Comp:  2               HeI5876      4.352      0.23     -33    42
# Comp:  2          [OIII]5007_d      48.87      0.28     -33    42
# Comp:  2            [OI]6300_d      2.013      0.28     -33    42
# Comp:  2           [NII]6583_d      40.30      0.28     -33    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124       517
#  comp.  1:       -38        35
#  comp.  2:       -32        40
# chi2/DOF: 1.782; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.80      0.22     -38    35
# Comp:  1                 Hbeta      37.15      0.22     -38    35
# Comp:  1                Halpha      119.6      0.22     -38    35
# Comp:  2             [SII]6716      13.45      0.22     -32    40
# Comp:  2             [SII]6731      10.44      0.22     -32    40
# Comp:  2              HeII4687     0.4171      0.22     -32    40
# Comp:  2               HeI5876      4.526      0.22     -32    40
# Comp:  2          [OIII]5007_d      49.62      0.28     -32    40
# Comp:  2            [OI]6300_d      1.981      0.28     -32    40
# Comp:  2           [NII]6583_d      38.13      0.28     -32    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -256       318
#  comp.  1:       -39        32
#  comp.  2:       -39        37
# chi2/DOF: 1.753; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.99      0.22     -39    32
# Comp:  1                 Hbeta      32.85      0.22     -39    32
# Comp:  1                Halpha      118.0      0.22     -39    32
# Comp:  2             [SII]6716      13.35      0.22     -39    37
# Comp:  2             [SII]6731      11.11      0.22     -39    37
# Comp:  2              HeII4687     0.6195      0.22     -39    37
# Comp:  2               HeI5876      3.897      0.22     -39    37
# Comp:  2          [OIII]5007_d      48.52      0.28     -39    37
# Comp:  2            [OI]6300_d      2.024      0.28     -39    37
# Comp:  2           [NII]6583_d      39.06      0.28     -39    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       715
#  comp.  1:       -36        31
#  comp.  2:       -36        32
# chi2/DOF: 1.772; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.77      0.22     -36    31
# Comp:  1                 Hbeta      36.76      0.22     -36    31
# Comp:  1                Halpha      117.4      0.22     -36    31
# Comp:  2             [SII]6716      12.35      0.22     -36    32
# Comp:  2             [SII]6731      11.39      0.22     -36    32
# Comp:  2              HeII4687     0.4679      0.22     -36    32
# Comp:  2               HeI5876      4.115      0.22     -36    32
# Comp:  2          [OIII]5007_d      45.95      0.28     -36    32
# Comp:  2            [OI]6300_d      1.904      0.28     -36    32
# Comp:  2           [NII]6583_d      38.18      0.28     -36    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -217       628
#  comp.  1:       -37        34
#  comp.  2:       -40        39
# chi2/DOF: 1.613; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.42      0.22     -37    34
# Comp:  1                 Hbeta      30.18      0.22     -37    34
# Comp:  1                Halpha      118.5      0.22     -37    34
# Comp:  2             [SII]6716      12.72      0.22     -40    39
# Comp:  2             [SII]6731      11.72      0.22     -40    39
# Comp:  2              HeII4687     0.3916      0.22     -40    39
# Comp:  2               HeI5876      4.302      0.22     -40    39
# Comp:  2          [OIII]5007_d      44.98      0.28     -40    39
# Comp:  2            [OI]6300_d      1.925      0.28     -40    39
# Comp:  2           [NII]6583_d      37.26      0.28     -40    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -270       754
#  comp.  1:       -37        37
#  comp.  2:       -36        43
# chi2/DOF: 1.638; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.27      0.22     -37    37
# Comp:  1                 Hbeta      39.43      0.22     -37    37
# Comp:  1                Halpha      117.6      0.22     -37    37
# Comp:  2             [SII]6716      12.79      0.23     -36    43
# Comp:  2             [SII]6731      10.60      0.23     -36    43
# Comp:  2              HeII4687     0.4592      0.23     -36    43
# Comp:  2               HeI5876      4.302      0.23     -36    43
# Comp:  2          [OIII]5007_d      47.97      0.29     -36    43
# Comp:  2            [OI]6300_d      2.023      0.29     -36    43
# Comp:  2           [NII]6583_d      38.88      0.29     -36    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -168       888
#  comp.  1:       -35        31
#  comp.  2:       -40        37
# chi2/DOF: 1.733; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.95      0.22     -35    31
# Comp:  1                 Hbeta      34.45      0.22     -35    31
# Comp:  1                Halpha      117.5      0.22     -35    31
# Comp:  2             [SII]6716      13.86      0.22     -40    37
# Comp:  2             [SII]6731      11.71      0.22     -40    37
# Comp:  2              HeII4687     0.3825      0.22     -40    37
# Comp:  2               HeI5876      4.269      0.22     -40    37
# Comp:  2          [OIII]5007_d      44.13      0.28     -40    37
# Comp:  2            [OI]6300_d      2.031      0.28     -40    37
# Comp:  2           [NII]6583_d      38.33      0.28     -40    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -605       933
#  comp.  1:       -38        30
#  comp.  2:       -35        28
# chi2/DOF: 1.598; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.43      0.22     -38    30
# Comp:  1                 Hbeta      30.12      0.22     -38    30
# Comp:  1                Halpha      119.1      0.22     -38    30
# Comp:  2             [SII]6716      12.56      0.22     -35    28
# Comp:  2             [SII]6731      10.82      0.22     -35    28
# Comp:  2              HeII4687     0.3406      0.22     -35    28
# Comp:  2               HeI5876      4.294      0.22     -35    28
# Comp:  2          [OIII]5007_d      46.04      0.27     -35    28
# Comp:  2            [OI]6300_d      1.967      0.27     -35    28
# Comp:  2           [NII]6583_d      37.52      0.27     -35    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -246       350
#  comp.  1:       -38        31
#  comp.  2:       -37        35
# chi2/DOF: 1.782; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.26      0.22     -38    31
# Comp:  1                 Hbeta      36.34      0.22     -38    31
# Comp:  1                Halpha      117.8      0.22     -38    31
# Comp:  2             [SII]6716      12.91      0.22     -37    35
# Comp:  2             [SII]6731      10.97      0.22     -37    35
# Comp:  2              HeII4687     0.5131      0.22     -37    35
# Comp:  2               HeI5876      4.481      0.22     -37    35
# Comp:  2          [OIII]5007_d      46.26      0.28     -37    35
# Comp:  2            [OI]6300_d      1.983      0.28     -37    35
# Comp:  2           [NII]6583_d      38.99      0.28     -37    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -207       637
#  comp.  1:       -37        28
#  comp.  2:       -33        42
# chi2/DOF: 1.677; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.22      0.22     -37    28
# Comp:  1                 Hbeta      36.29      0.22     -37    28
# Comp:  1                Halpha      118.8      0.22     -37    28
# Comp:  2             [SII]6716      14.46      0.23     -33    42
# Comp:  2             [SII]6731      10.54      0.23     -33    42
# Comp:  2              HeII4687     0.5293      0.23     -33    42
# Comp:  2               HeI5876      4.556      0.23     -33    42
# Comp:  2          [OIII]5007_d      50.00      0.28     -33    42
# Comp:  2            [OI]6300_d      1.993      0.28     -33    42
# Comp:  2           [NII]6583_d      38.42      0.28     -33    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128       445
#  comp.  1:       -38        29
#  comp.  2:       -39        37
# chi2/DOF: 1.669; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.49      0.22     -38    29
# Comp:  1                 Hbeta      32.11      0.22     -38    29
# Comp:  1                Halpha      119.2      0.22     -38    29
# Comp:  2             [SII]6716      12.65      0.22     -39    37
# Comp:  2             [SII]6731      11.07      0.22     -39    37
# Comp:  2              HeII4687     0.4054      0.22     -39    37
# Comp:  2               HeI5876      3.866      0.22     -39    37
# Comp:  2          [OIII]5007_d      44.69      0.28     -39    37
# Comp:  2            [OI]6300_d      1.897      0.28     -39    37
# Comp:  2           [NII]6583_d      39.48      0.28     -39    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99       733
#  comp.  1:       -39        38
#  comp.  2:       -38        35
# chi2/DOF: 1.694; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.88      0.22     -39    38
# Comp:  1                 Hbeta      33.54      0.22     -39    38
# Comp:  1                Halpha      120.8      0.22     -39    38
# Comp:  2             [SII]6716      14.19      0.22     -38    35
# Comp:  2             [SII]6731      10.25      0.22     -38    35
# Comp:  2              HeII4687     0.5218      0.22     -38    35
# Comp:  2               HeI5876      4.291      0.22     -38    35
# Comp:  2          [OIII]5007_d      47.76      0.28     -38    35
# Comp:  2            [OI]6300_d      1.919      0.28     -38    35
# Comp:  2           [NII]6583_d      39.07      0.28     -38    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -205       386
#  comp.  1:       -37        39
#  comp.  2:       -34        38
# chi2/DOF: 1.782; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.09      0.22     -37    39
# Comp:  1                 Hbeta      35.45      0.22     -37    39
# Comp:  1                Halpha      118.4      0.22     -37    39
# Comp:  2             [SII]6716      13.64      0.22     -34    38
# Comp:  2             [SII]6731      11.53      0.22     -34    38
# Comp:  2              HeII4687     0.4980      0.22     -34    38
# Comp:  2               HeI5876      4.353      0.22     -34    38
# Comp:  2          [OIII]5007_d      46.67      0.28     -34    38
# Comp:  2            [OI]6300_d      2.019      0.28     -34    38
# Comp:  2           [NII]6583_d      37.84      0.28     -34    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -222       862
#  comp.  1:       -35        31
#  comp.  2:       -33        44
# chi2/DOF: 1.681; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.40      0.22     -35    31
# Comp:  1                 Hbeta      32.42      0.22     -35    31
# Comp:  1                Halpha      117.0      0.22     -35    31
# Comp:  2             [SII]6716      14.53      0.23     -33    44
# Comp:  2             [SII]6731      11.23      0.23     -33    44
# Comp:  2              HeII4687     0.6648      0.23     -33    44
# Comp:  2               HeI5876      3.703      0.23     -33    44
# Comp:  2          [OIII]5007_d      50.01      0.29     -33    44
# Comp:  2            [OI]6300_d      1.995      0.29     -33    44
# Comp:  2           [NII]6583_d      38.11      0.29     -33    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48       986
#  comp.  1:       -38        37
#  comp.  2:       -34        32
# chi2/DOF: 1.781; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.60      0.22     -38    37
# Comp:  1                 Hbeta      33.32      0.22     -38    37
# Comp:  1                Halpha      119.9      0.22     -38    37
# Comp:  2             [SII]6716      12.27      0.22     -34    32
# Comp:  2             [SII]6731      10.67      0.22     -34    32
# Comp:  2              HeII4687     0.5985      0.22     -34    32
# Comp:  2               HeI5876      3.970      0.22     -34    32
# Comp:  2          [OIII]5007_d      46.14      0.28     -34    32
# Comp:  2            [OI]6300_d      1.896      0.28     -34    32
# Comp:  2           [NII]6583_d      37.29      0.28     -34    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37       778
#  comp.  1:       -36        29
#  comp.  2:       -32        46
# chi2/DOF: 1.746; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.72      0.22     -36    29
# Comp:  1                 Hbeta      34.63      0.22     -36    29
# Comp:  1                Halpha      116.6      0.22     -36    29
# Comp:  2             [SII]6716      14.43      0.23     -32    46
# Comp:  2             [SII]6731      11.44      0.23     -32    46
# Comp:  2              HeII4687     0.4737      0.23     -32    46
# Comp:  2               HeI5876      3.913      0.23     -32    46
# Comp:  2          [OIII]5007_d      50.61      0.29     -32    46
# Comp:  2            [OI]6300_d      2.121      0.29     -32    46
# Comp:  2           [NII]6583_d      39.21      0.29     -32    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123       493
#  comp.  1:       -36        34
#  comp.  2:       -34        42
# chi2/DOF: 1.758; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.73      0.22     -36    34
# Comp:  1                 Hbeta      35.11      0.22     -36    34
# Comp:  1                Halpha      116.4      0.22     -36    34
# Comp:  2             [SII]6716      12.87      0.23     -34    42
# Comp:  2             [SII]6731      12.08      0.23     -34    42
# Comp:  2              HeII4687     0.4022      0.23     -34    42
# Comp:  2               HeI5876      4.665      0.23     -34    42
# Comp:  2          [OIII]5007_d      48.88      0.28     -34    42
# Comp:  2            [OI]6300_d      2.056      0.28     -34    42
# Comp:  2           [NII]6583_d      39.80      0.28     -34    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -37        37
#  comp.  2:       -32        41
# chi2/DOF: 1.679; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.04      0.22     -37    37
# Comp:  1                 Hbeta      38.99      0.22     -37    37
# Comp:  1                Halpha      118.0      0.22     -37    37
# Comp:  2             [SII]6716      13.98      0.22     -32    41
# Comp:  2             [SII]6731      10.28      0.22     -32    41
# Comp:  2              HeII4687     0.5789      0.22     -32    41
# Comp:  2               HeI5876      4.287      0.22     -32    41
# Comp:  2          [OIII]5007_d      46.15      0.28     -32    41
# Comp:  2            [OI]6300_d      2.079      0.28     -32    41
# Comp:  2           [NII]6583_d      38.76      0.28     -32    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89       202
#  comp.  1:       -35        31
#  comp.  2:       -33        41
# chi2/DOF: 1.565; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.42      0.22     -35    31
# Comp:  1                 Hbeta      39.53      0.22     -35    31
# Comp:  1                Halpha      117.6      0.22     -35    31
# Comp:  2             [SII]6716      12.73      0.22     -33    41
# Comp:  2             [SII]6731      11.34      0.22     -33    41
# Comp:  2              HeII4687     0.5455      0.22     -33    41
# Comp:  2               HeI5876      4.667      0.22     -33    41
# Comp:  2          [OIII]5007_d      50.46      0.28     -33    41
# Comp:  2            [OI]6300_d      2.062      0.28     -33    41
# Comp:  2           [NII]6583_d      39.99      0.28     -33    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -615      1000
#  comp.  1:       -38        36
#  comp.  2:       -37        49
# chi2/DOF: 1.710; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.83      0.22     -38    36
# Comp:  1                 Hbeta      33.22      0.22     -38    36
# Comp:  1                Halpha      121.7      0.22     -38    36
# Comp:  2             [SII]6716      14.51      0.23     -37    49
# Comp:  2             [SII]6731      12.21      0.23     -37    49
# Comp:  2              HeII4687     0.5196      0.23     -37    49
# Comp:  2               HeI5876      4.449      0.23     -37    49
# Comp:  2          [OIII]5007_d      49.70      0.29     -37    49
# Comp:  2            [OI]6300_d      2.111      0.29     -37    49
# Comp:  2           [NII]6583_d      40.14      0.29     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140         1
#  comp.  1:       -37        38
#  comp.  2:       -41        43
# chi2/DOF: 1.561; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.30      0.22     -37    38
# Comp:  1                 Hbeta      40.29      0.22     -37    38
# Comp:  1                Halpha      118.4      0.22     -37    38
# Comp:  2             [SII]6716      12.91      0.23     -41    43
# Comp:  2             [SII]6731      11.42      0.23     -41    43
# Comp:  2              HeII4687     0.2910      0.23     -41    43
# Comp:  2               HeI5876      3.763      0.23     -41    43
# Comp:  2          [OIII]5007_d      45.59      0.29     -41    43
# Comp:  2            [OI]6300_d      2.154      0.29     -41    43
# Comp:  2           [NII]6583_d      39.25      0.29     -41    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -150       387
#  comp.  1:       -37        36
#  comp.  2:       -37        30
# chi2/DOF: 1.770; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.08      0.22     -37    36
# Comp:  1                 Hbeta      34.90      0.22     -37    36
# Comp:  1                Halpha      117.0      0.22     -37    36
# Comp:  2             [SII]6716      12.36      0.22     -37    30
# Comp:  2             [SII]6731      11.58      0.22     -37    30
# Comp:  2              HeII4687     0.3935      0.22     -37    30
# Comp:  2               HeI5876      3.872      0.22     -37    30
# Comp:  2          [OIII]5007_d      47.20      0.27     -37    30
# Comp:  2            [OI]6300_d      2.042      0.27     -37    30
# Comp:  2           [NII]6583_d      37.52      0.27     -37    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        88
#  comp.  1:       -36        28
#  comp.  2:       -35        47
# chi2/DOF: 1.720; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.68      0.22     -36    28
# Comp:  1                 Hbeta      35.02      0.22     -36    28
# Comp:  1                Halpha      116.9      0.22     -36    28
# Comp:  2             [SII]6716      14.20      0.23     -35    47
# Comp:  2             [SII]6731      11.57      0.23     -35    47
# Comp:  2              HeII4687     0.3147      0.23     -35    47
# Comp:  2               HeI5876      4.001      0.23     -35    47
# Comp:  2          [OIII]5007_d      48.66      0.29     -35    47
# Comp:  2            [OI]6300_d      2.011      0.29     -35    47
# Comp:  2           [NII]6583_d      39.89      0.29     -35    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -218       574
#  comp.  1:       -36        34
#  comp.  2:       -37        32
# chi2/DOF: 1.524; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.82      0.22     -36    34
# Comp:  1                 Hbeta      30.36      0.22     -36    34
# Comp:  1                Halpha      116.4      0.22     -36    34
# Comp:  2             [SII]6716      13.52      0.22     -37    32
# Comp:  2             [SII]6731      10.20      0.22     -37    32
# Comp:  2              HeII4687     0.4507      0.22     -37    32
# Comp:  2               HeI5876      3.923      0.22     -37    32
# Comp:  2          [OIII]5007_d      47.00      0.28     -37    32
# Comp:  2            [OI]6300_d      1.921      0.28     -37    32
# Comp:  2           [NII]6583_d      38.34      0.28     -37    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114       651
#  comp.  1:       -39        32
#  comp.  2:       -32        39
# chi2/DOF: 1.682; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.84      0.22     -39    32
# Comp:  1                 Hbeta      36.96      0.22     -39    32
# Comp:  1                Halpha      118.2      0.22     -39    32
# Comp:  2             [SII]6716      14.34      0.22     -32    39
# Comp:  2             [SII]6731      11.75      0.22     -32    39
# Comp:  2              HeII4687     0.5127      0.22     -32    39
# Comp:  2               HeI5876      4.015      0.22     -32    39
# Comp:  2          [OIII]5007_d      49.85      0.28     -32    39
# Comp:  2            [OI]6300_d      1.985      0.28     -32    39
# Comp:  2           [NII]6583_d      37.98      0.28     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -515       910
#  comp.  1:       -38        33
#  comp.  2:       -35        34
# chi2/DOF: 1.657; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.49      0.22     -38    33
# Comp:  1                 Hbeta      30.20      0.22     -38    33
# Comp:  1                Halpha      118.6      0.22     -38    33
# Comp:  2             [SII]6716      12.35      0.22     -35    34
# Comp:  2             [SII]6731      11.74      0.22     -35    34
# Comp:  2              HeII4687     0.6866      0.22     -35    34
# Comp:  2               HeI5876      3.879      0.22     -35    34
# Comp:  2          [OIII]5007_d      47.02      0.28     -35    34
# Comp:  2            [OI]6300_d      1.921      0.28     -35    34
# Comp:  2           [NII]6583_d      37.41      0.28     -35    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85       106
#  comp.  1:       -39        39
#  comp.  2:       -32        40
# chi2/DOF: 1.741; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.43      0.22     -39    39
# Comp:  1                 Hbeta      36.67      0.22     -39    39
# Comp:  1                Halpha      121.4      0.22     -39    39
# Comp:  2             [SII]6716      13.31      0.22     -32    40
# Comp:  2             [SII]6731      10.96      0.22     -32    40
# Comp:  2              HeII4687     0.5209      0.22     -32    40
# Comp:  2               HeI5876      4.084      0.22     -32    40
# Comp:  2          [OIII]5007_d      45.55      0.28     -32    40
# Comp:  2            [OI]6300_d      1.924      0.28     -32    40
# Comp:  2           [NII]6583_d      38.32      0.28     -32    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -363      1000
#  comp.  1:       -36        30
#  comp.  2:       -38        37
# chi2/DOF: 1.680; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.30      0.22     -36    30
# ...
# Comp:  2           [NII]6583_d      38.41      0.28     -39    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -267       654
#  comp.  1:       -37        31
#  comp.  2:       -31        43
# chi2/DOF: 1.645; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.62      0.22     -37    31
# Comp:  1                 Hbeta      37.23      0.22     -37    31
# Comp:  1                Halpha      120.1      0.22     -37    31
# Comp:  2             [SII]6716      13.82      0.23     -31    43
# Comp:  2             [SII]6731      11.47      0.23     -31    43
# Comp:  2              HeII4687     0.5431      0.23     -31    43
# Comp:  2               HeI5876      4.533      0.23     -31    43
# Comp:  2          [OIII]5007_d      50.82      0.29     -31    43
# Comp:  2            [OI]6300_d      1.968      0.29     -31    43
# Comp:  2           [NII]6583_d      40.02      0.29     -31    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -803      1000
#  comp.  1:       -36        35
#  comp.  2:       -43        42
# chi2/DOF: 1.647; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.13      0.22     -36    35
# Comp:  1                 Hbeta      33.33      0.22     -36    35
# Comp:  1                Halpha      116.5      0.22     -36    35
# Comp:  2             [SII]6716      12.45      0.23     -43    42
# Comp:  2             [SII]6731      11.74      0.23     -43    42
# Comp:  2              HeII4687     0.4592      0.23     -43    42
# Comp:  2               HeI5876      4.924      0.23     -43    42
# Comp:  2          [OIII]5007_d      46.50      0.28     -43    42
# Comp:  2            [OI]6300_d      2.150      0.28     -43    42
# Comp:  2           [NII]6583_d      39.86      0.28     -43    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27       830
#  comp.  1:       -35        30
#  comp.  2:       -33        30
# chi2/DOF: 1.642; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.14      0.22     -35    30
# Comp:  1                 Hbeta      36.91      0.22     -35    30
# Comp:  1                Halpha      117.0      0.22     -35    30
# Comp:  2             [SII]6716      12.41      0.22     -33    30
# Comp:  2             [SII]6731      10.11      0.22     -33    30
# Comp:  2              HeII4687     0.6425      0.22     -33    30
# Comp:  2               HeI5876      4.144      0.22     -33    30
# Comp:  2          [OIII]5007_d      46.55      0.27     -33    30
# Comp:  2            [OI]6300_d      2.000      0.27     -33    30
# Comp:  2           [NII]6583_d      37.05      0.27     -33    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129         1
#  comp.  1:       -36        34
#  comp.  2:       -41        33
# chi2/DOF: 1.597; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.05      0.22     -36    34
# Comp:  1                 Hbeta      33.27      0.22     -36    34
# Comp:  1                Halpha      116.1      0.22     -36    34
# Comp:  2             [SII]6716      12.11      0.22     -41    33
# Comp:  2             [SII]6731      10.92      0.22     -41    33
# Comp:  2              HeII4687     0.3949      0.22     -41    33
# Comp:  2               HeI5876      4.136      0.22     -41    33
# Comp:  2          [OIII]5007_d      44.92      0.28     -41    33
# Comp:  2            [OI]6300_d      2.066      0.28     -41    33
# Comp:  2           [NII]6583_d      38.82      0.28     -41    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113       417
#  comp.  1:       -38        34
#  comp.  2:       -37        35
# chi2/DOF: 1.717; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.21      0.22     -38    34
# Comp:  1                 Hbeta      37.01      0.22     -38    34
# Comp:  1                Halpha      121.2      0.22     -38    34
# Comp:  2             [SII]6716      13.21      0.22     -37    35
# Comp:  2             [SII]6731      10.81      0.22     -37    35
# Comp:  2              HeII4687     0.4875      0.22     -37    35
# Comp:  2               HeI5876      4.368      0.22     -37    35
# Comp:  2          [OIII]5007_d      45.83      0.28     -37    35
# Comp:  2            [OI]6300_d      1.880      0.28     -37    35
# Comp:  2           [NII]6583_d      39.28      0.28     -37    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -297       657
#  comp.  1:       -37        33
#  comp.  2:       -39        36
# chi2/DOF: 1.609; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.89      0.22     -37    33
# Comp:  1                 Hbeta      39.00      0.22     -37    33
# Comp:  1                Halpha      118.2      0.22     -37    33
# Comp:  2             [SII]6716      13.41      0.22     -39    36
# Comp:  2             [SII]6731      10.31      0.22     -39    36
# Comp:  2              HeII4687     0.5905      0.22     -39    36
# Comp:  2               HeI5876      3.882      0.22     -39    36
# Comp:  2          [OIII]5007_d      43.61      0.28     -39    36
# Comp:  2            [OI]6300_d      2.045      0.28     -39    36
# Comp:  2           [NII]6583_d      38.91      0.28     -39    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30       409
#  comp.  1:       -37        36
#  comp.  2:       -40        39
# chi2/DOF: 1.622; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.87      0.22     -37    36
# Comp:  1                 Hbeta      39.98      0.22     -37    36
# Comp:  1                Halpha      119.3      0.22     -37    36
# Comp:  2             [SII]6716      13.48      0.22     -40    39
# Comp:  2             [SII]6731      11.84      0.22     -40    39
# Comp:  2              HeII4687     0.6622      0.22     -40    39
# Comp:  2               HeI5876      3.905      0.22     -40    39
# Comp:  2          [OIII]5007_d      44.72      0.28     -40    39
# Comp:  2            [OI]6300_d      1.829      0.28     -40    39
# Comp:  2           [NII]6583_d      39.29      0.28     -40    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       118         1
#  comp.  1:       -37        38
#  comp.  2:       -31        40
# chi2/DOF: 1.670; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.14      0.22     -37    38
# Comp:  1                 Hbeta      36.04      0.22     -37    38
# Comp:  1                Halpha      118.1      0.22     -37    38
# Comp:  2             [SII]6716      13.26      0.22     -31    40
# Comp:  2             [SII]6731      11.10      0.22     -31    40
# Comp:  2              HeII4687     0.5587      0.22     -31    40
# Comp:  2               HeI5876      4.405      0.22     -31    40
# Comp:  2          [OIII]5007_d      48.38      0.28     -31    40
# Comp:  2            [OI]6300_d      1.982      0.28     -31    40
# Comp:  2           [NII]6583_d      38.98      0.28     -31    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -152       823
#  comp.  1:       -37        35
#  comp.  2:       -36        42
# chi2/DOF: 1.777; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.30      0.22     -37    35
# Comp:  1                 Hbeta      32.50      0.22     -37    35
# Comp:  1                Halpha      118.9      0.22     -37    35
# Comp:  2             [SII]6716      12.99      0.23     -36    42
# Comp:  2             [SII]6731      11.20      0.23     -36    42
# Comp:  2              HeII4687     0.4832      0.23     -36    42
# Comp:  2               HeI5876      4.715      0.23     -36    42
# Comp:  2          [OIII]5007_d      48.36      0.29     -36    42
# Comp:  2            [OI]6300_d      1.965      0.29     -36    42
# Comp:  2           [NII]6583_d      39.01      0.29     -36    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -294       868
#  comp.  1:       -35        31
#  comp.  2:       -35        42
# chi2/DOF: 1.722; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.64      0.22     -35    31
# Comp:  1                 Hbeta      32.34      0.22     -35    31
# Comp:  1                Halpha      117.5      0.22     -35    31
# Comp:  2             [SII]6716      14.44      0.23     -35    42
# Comp:  2             [SII]6731      11.90      0.23     -35    42
# Comp:  2              HeII4687     0.4943      0.23     -35    42
# Comp:  2               HeI5876      3.663      0.23     -35    42
# Comp:  2          [OIII]5007_d      46.41      0.28     -35    42
# Comp:  2            [OI]6300_d      2.076      0.28     -35    42
# Comp:  2           [NII]6583_d      39.38      0.28     -35    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       264      1000
#  comp.  1:       -37        39
#  comp.  2:       -35        41
# chi2/DOF: 1.731; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.36      0.22     -37    39
# Comp:  1                 Hbeta      33.74      0.22     -37    39
# Comp:  1                Halpha      118.1      0.22     -37    39
# Comp:  2             [SII]6716      12.64      0.22     -35    41
# Comp:  2             [SII]6731      11.82      0.22     -35    41
# Comp:  2              HeII4687     0.6955      0.22     -35    41
# Comp:  2               HeI5876      4.130      0.22     -35    41
# Comp:  2          [OIII]5007_d      46.19      0.28     -35    41
# Comp:  2            [OI]6300_d      2.118      0.28     -35    41
# Comp:  2           [NII]6583_d      39.07      0.28     -35    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151       577
#  comp.  1:       -37        31
#  comp.  2:       -37        35
# chi2/DOF: 1.784; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.05      0.22     -37    31
# Comp:  1                 Hbeta      36.66      0.22     -37    31
# Comp:  1                Halpha      117.7      0.22     -37    31
# Comp:  2             [SII]6716      12.65      0.22     -37    35
# Comp:  2             [SII]6731      11.85      0.22     -37    35
# Comp:  2              HeII4687     0.4609      0.22     -37    35
# Comp:  2               HeI5876      3.985      0.22     -37    35
# Comp:  2          [OIII]5007_d      45.13      0.28     -37    35
# Comp:  2            [OI]6300_d      1.907      0.28     -37    35
# Comp:  2           [NII]6583_d      37.48      0.28     -37    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -439      1000
#  comp.  1:       -36        35
#  comp.  2:       -34        42
# chi2/DOF: 1.752; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.90      0.22     -36    35
# Comp:  1                 Hbeta      37.51      0.22     -36    35
# Comp:  1                Halpha      118.8      0.22     -36    35
# Comp:  2             [SII]6716      13.62      0.23     -34    42
# Comp:  2             [SII]6731      11.16      0.23     -34    42
# Comp:  2              HeII4687     0.5655      0.23     -34    42
# Comp:  2               HeI5876      3.950      0.23     -34    42
# Comp:  2          [OIII]5007_d      50.21      0.28     -34    42
# Comp:  2            [OI]6300_d      1.986      0.28     -34    42
# Comp:  2           [NII]6583_d      39.03      0.28     -34    42
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_2_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
