# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_1.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/FORS2.2022-01-29T07_05_26.457/Spectra_extraction/redshift.txt")
z = 0.0238  
wv_mask = wv > 0
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       639       204
# chi2/DOF: 0.01256; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
# chi2/DOF: 0.007277; DOF: 2012; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [3.29527846 2.57614141 1.24142395 ... 0.70936205 0.73873382 0.73580538]
# [1.53952877 1.53478392 1.5372413  ... 0.78881665 0.79014308 0.78962111]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-58.03328091,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       343      1000
#  comp.  1:       -36        33
#  comp.  2:       -33        41
# chi2/DOF: 3.004; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.61      0.19     -36    33
# Comp:  1                 Hbeta      43.26      0.19     -36    33
# Comp:  1                Halpha      138.8      0.19     -36    33
# Comp:  2             [SII]6716      12.99      0.20     -33    41
# Comp:  2             [SII]6731      11.12      0.20     -33    41
# Comp:  2              HeII4687     0.4668      0.20     -33    41
# Comp:  2               HeI5876      5.511      0.20     -33    41
# Comp:  2          [OIII]5007_d      71.82      0.25     -33    41
# Comp:  2            [OI]6300_d      1.682      0.25     -33    41
# Comp:  2           [NII]6583_d      40.48      0.25     -33    41
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  72.74; gas flux:     17 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  178.5; gas flux:     44 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  564.6; gas flux:    190 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  50.19; gas flux:     18 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   43.7; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.733; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  20.15; gas flux:      7 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  201.6; gas flux:     75 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.951; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  119.1; gas flux:     56 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       123       900
#  comp.  1:       -36        33
#  comp.  2:       -35        48
# chi2/DOF: 2.775; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.21      0.19     -36    33
# Comp:  1                 Hbeta      44.85      0.19     -36    33
# Comp:  1                Halpha      138.8      0.19     -36    33
# Comp:  2             [SII]6716      13.47      0.20     -35    48
# Comp:  2             [SII]6731      11.58      0.20     -35    48
# Comp:  2              HeII4687     0.4450      0.20     -35    48
# Comp:  2               HeI5876      5.778      0.20     -35    48
# Comp:  2          [OIII]5007_d      75.77      0.26     -35    48
# Comp:  2            [OI]6300_d      1.921      0.26     -35    48
# Comp:  2           [NII]6583_d      39.85      0.26     -35    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       308      1000
#  comp.  1:       -37        37
#  comp.  2:       -32        28
# chi2/DOF: 2.533; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.12      0.20     -37    37
# Comp:  1                 Hbeta      43.48      0.20     -37    37
# Comp:  1                Halpha      141.7      0.20     -37    37
# Comp:  2             [SII]6716      12.36      0.19     -32    28
# Comp:  2             [SII]6731      9.802      0.19     -32    28
# Comp:  2              HeII4687     0.4884      0.19     -32    28
# Comp:  2               HeI5876      5.530      0.19     -32    28
# Comp:  2          [OIII]5007_d      70.63      0.24     -32    28
# Comp:  2            [OI]6300_d      1.560      0.24     -32    28
# Comp:  2           [NII]6583_d      38.81      0.24     -32    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       373       883
#  comp.  1:       -37        29
#  comp.  2:       -30        40
# chi2/DOF: 2.762; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.44      0.19     -37    29
# Comp:  1                 Hbeta      42.91      0.19     -37    29
# Comp:  1                Halpha      139.4      0.19     -37    29
# Comp:  2             [SII]6716      11.87      0.20     -30    40
# Comp:  2             [SII]6731      11.98      0.20     -30    40
# Comp:  2              HeII4687     0.4668      0.20     -30    40
# Comp:  2               HeI5876      5.922      0.20     -30    40
# Comp:  2          [OIII]5007_d      71.32      0.25     -30    40
# Comp:  2            [OI]6300_d      1.778      0.25     -30    40
# Comp:  2           [NII]6583_d      39.87      0.25     -30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        92         1
#  comp.  1:       -35        38
#  comp.  2:       -33        36
# chi2/DOF: 2.636; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.61      0.20     -35    38
# Comp:  1                 Hbeta      45.53      0.20     -35    38
# Comp:  1                Halpha      139.4      0.20     -35    38
# Comp:  2             [SII]6716      12.40      0.20     -33    36
# Comp:  2             [SII]6731      12.00      0.20     -33    36
# Comp:  2              HeII4687     0.4158      0.20     -33    36
# Comp:  2               HeI5876      5.373      0.20     -33    36
# Comp:  2          [OIII]5007_d      70.05      0.25     -33    36
# Comp:  2            [OI]6300_d      1.754      0.25     -33    36
# Comp:  2           [NII]6583_d      37.97      0.25     -33    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       495       639
#  comp.  1:       -35        35
#  comp.  2:       -34        52
# chi2/DOF: 2.735; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.44      0.20     -35    35
# Comp:  1                 Hbeta      42.09      0.20     -35    35
# Comp:  1                Halpha      140.0      0.20     -35    35
# Comp:  2             [SII]6716      13.51      0.21     -34    52
# Comp:  2             [SII]6731      11.99      0.21     -34    52
# Comp:  2              HeII4687     0.4851      0.21     -34    52
# Comp:  2               HeI5876      5.363      0.21     -34    52
# Comp:  2          [OIII]5007_d      74.06      0.26     -34    52
# Comp:  2            [OI]6300_d      1.834      0.26     -34    52
# Comp:  2           [NII]6583_d      41.89      0.26     -34    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50       601
#  comp.  1:       -37        30
#  comp.  2:       -37        28
# chi2/DOF: 2.623; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.10      0.19     -37    30
# Comp:  1                 Hbeta      43.19      0.19     -37    30
# Comp:  1                Halpha      137.9      0.19     -37    30
# Comp:  2             [SII]6716      12.95      0.19     -37    28
# Comp:  2             [SII]6731      10.62      0.19     -37    28
# Comp:  2              HeII4687     0.4450      0.19     -37    28
# Comp:  2               HeI5876      5.269      0.19     -37    28
# Comp:  2          [OIII]5007_d      66.56      0.24     -37    28
# Comp:  2            [OI]6300_d      1.458      0.24     -37    28
# Comp:  2           [NII]6583_d      39.56      0.24     -37    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       595       672
#  comp.  1:       -34        34
#  comp.  2:       -38        36
# chi2/DOF: 2.602; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.07      0.19     -34    34
# Comp:  1                 Hbeta      42.10      0.19     -34    34
# Comp:  1                Halpha      136.6      0.19     -34    34
# Comp:  2             [SII]6716      12.40      0.20     -38    36
# Comp:  2             [SII]6731      11.52      0.20     -38    36
# Comp:  2              HeII4687     0.3182      0.20     -38    36
# Comp:  2               HeI5876      4.907      0.20     -38    36
# Comp:  2          [OIII]5007_d      68.89      0.25     -38    36
# Comp:  2            [OI]6300_d      1.679      0.25     -38    36
# Comp:  2           [NII]6583_d      39.93      0.25     -38    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       819      1000
#  comp.  1:       -35        28
#  comp.  2:       -33        48
# chi2/DOF: 2.684; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.70      0.19     -35    28
# Comp:  1                 Hbeta      41.95      0.19     -35    28
# Comp:  1                Halpha      136.0      0.19     -35    28
# Comp:  2             [SII]6716      12.32      0.20     -33    48
# Comp:  2             [SII]6731      11.50      0.20     -33    48
# Comp:  2              HeII4687     0.4742      0.20     -33    48
# Comp:  2               HeI5876      5.720      0.20     -33    48
# Comp:  2          [OIII]5007_d      71.83      0.26     -33    48
# Comp:  2            [OI]6300_d      1.734      0.26     -33    48
# Comp:  2           [NII]6583_d      41.66      0.26     -33    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       364      1000
#  comp.  1:       -37        28
#  comp.  2:       -29        42
# chi2/DOF: 2.489; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.60      0.19     -37    28
# Comp:  1                 Hbeta      47.32      0.19     -37    28
# Comp:  1                Halpha      138.8      0.19     -37    28
# Comp:  2             [SII]6716      12.97      0.20     -29    42
# Comp:  2             [SII]6731      10.91      0.20     -29    42
# Comp:  2              HeII4687     0.5374      0.20     -29    42
# Comp:  2               HeI5876      5.140      0.20     -29    42
# Comp:  2          [OIII]5007_d      72.90      0.25     -29    42
# Comp:  2            [OI]6300_d      1.772      0.25     -29    42
# Comp:  2           [NII]6583_d      40.45      0.25     -29    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       836      1000
#  comp.  1:       -35        31
#  comp.  2:       -27        37
# chi2/DOF: 2.407; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.08      0.19     -35    31
# Comp:  1                 Hbeta      39.33      0.19     -35    31
# Comp:  1                Halpha      137.0      0.19     -35    31
# Comp:  2             [SII]6716      13.15      0.20     -27    37
# Comp:  2             [SII]6731      12.13      0.20     -27    37
# Comp:  2              HeII4687     0.4517      0.20     -27    37
# Comp:  2               HeI5876      4.934      0.20     -27    37
# Comp:  2          [OIII]5007_d      74.80      0.25     -27    37
# Comp:  2            [OI]6300_d      1.612      0.25     -27    37
# Comp:  2           [NII]6583_d      39.66      0.25     -27    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       571       440
#  comp.  1:       -35        34
#  comp.  2:       -36        48
# chi2/DOF: 2.684; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.99      0.19     -35    34
# Comp:  1                 Hbeta      47.31      0.19     -35    34
# Comp:  1                Halpha      138.6      0.19     -35    34
# Comp:  2             [SII]6716      13.06      0.20     -36    48
# Comp:  2             [SII]6731      10.47      0.20     -36    48
# Comp:  2              HeII4687     0.4043      0.20     -36    48
# Comp:  2               HeI5876      5.696      0.20     -36    48
# Comp:  2          [OIII]5007_d      75.51      0.26     -36    48
# Comp:  2            [OI]6300_d      1.694      0.26     -36    48
# Comp:  2           [NII]6583_d      41.35      0.26     -36    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -341      1000
#  comp.  1:       -37        32
#  comp.  2:       -30        46
# chi2/DOF: 2.539; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.30      0.19     -37    32
# Comp:  1                 Hbeta      39.55      0.19     -37    32
# Comp:  1                Halpha      138.6      0.19     -37    32
# Comp:  2             [SII]6716      13.52      0.20     -30    46
# Comp:  2             [SII]6731      10.58      0.20     -30    46
# Comp:  2              HeII4687     0.6078      0.20     -30    46
# Comp:  2               HeI5876      5.896      0.20     -30    46
# Comp:  2          [OIII]5007_d      73.69      0.26     -30    46
# Comp:  2            [OI]6300_d      1.712      0.26     -30    46
# Comp:  2           [NII]6583_d      41.63      0.26     -30    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       952      1000
#  comp.  1:       -37        38
#  comp.  2:       -30        45
# chi2/DOF: 2.477; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.56      0.20     -37    38
# Comp:  1                 Hbeta      40.82      0.20     -37    38
# Comp:  1                Halpha      138.3      0.20     -37    38
# Comp:  2             [SII]6716      12.02      0.20     -30    45
# Comp:  2             [SII]6731      10.48      0.20     -30    45
# Comp:  2              HeII4687     0.4179      0.20     -30    45
# Comp:  2               HeI5876      5.656      0.20     -30    45
# Comp:  2          [OIII]5007_d      74.37      0.25     -30    45
# Comp:  2            [OI]6300_d      1.696      0.25     -30    45
# Comp:  2           [NII]6583_d      42.94      0.25     -30    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        84
#  comp.  1:       -37        34
#  comp.  2:       -29        37
# chi2/DOF: 2.649; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 73; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.01      0.19     -37    34
# Comp:  1                 Hbeta      47.22      0.19     -37    34
# Comp:  1                Halpha      140.1      0.19     -37    34
# Comp:  2             [SII]6716      13.05      0.20     -29    37
# Comp:  2             [SII]6731      10.07      0.20     -29    37
# Comp:  2              HeII4687     0.3705      0.20     -29    37
# Comp:  2               HeI5876      5.869      0.20     -29    37
# Comp:  2          [OIII]5007_d      74.66      0.25     -29    37
# Comp:  2            [OI]6300_d      1.673      0.25     -29    37
# Comp:  2           [NII]6583_d      38.47      0.25     -29    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       297      1000
#  comp.  1:       -38        32
#  comp.  2:       -38        37
# chi2/DOF: 2.517; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.08      0.19     -38    32
# Comp:  1                 Hbeta      40.03      0.19     -38    32
# Comp:  1                Halpha      138.3      0.19     -38    32
# Comp:  2             [SII]6716      13.10      0.20     -38    37
# Comp:  2             [SII]6731      11.11      0.20     -38    37
# Comp:  2              HeII4687     0.5251      0.20     -38    37
# Comp:  2               HeI5876      5.133      0.20     -38    37
# Comp:  2          [OIII]5007_d      74.28      0.25     -38    37
# Comp:  2            [OI]6300_d      1.732      0.25     -38    37
# Comp:  2           [NII]6583_d      40.49      0.25     -38    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       217      1000
#  comp.  1:       -35        31
#  comp.  2:       -36        35
# chi2/DOF: 2.752; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.24      0.19     -35    31
# Comp:  1                 Hbeta      44.94      0.19     -35    31
# Comp:  1                Halpha      137.5      0.19     -35    31
# Comp:  2             [SII]6716      12.18      0.20     -36    35
# Comp:  2             [SII]6731      11.56      0.20     -36    35
# Comp:  2              HeII4687     0.4069      0.20     -36    35
# Comp:  2               HeI5876      5.394      0.20     -36    35
# Comp:  2          [OIII]5007_d      69.94      0.25     -36    35
# Comp:  2            [OI]6300_d      1.562      0.25     -36    35
# Comp:  2           [NII]6583_d      40.18      0.25     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        97         1
#  comp.  1:       -36        34
#  comp.  2:       -40        42
# chi2/DOF: 2.236; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.88      0.19     -36    34
# Comp:  1                 Hbeta      38.24      0.19     -36    34
# Comp:  1                Halpha      138.9      0.19     -36    34
# Comp:  2             [SII]6716      11.88      0.20     -40    42
# Comp:  2             [SII]6731      11.98      0.20     -40    42
# Comp:  2              HeII4687     0.2934      0.20     -40    42
# Comp:  2               HeI5876      5.642      0.20     -40    42
# Comp:  2          [OIII]5007_d      68.78      0.25     -40    42
# Comp:  2            [OI]6300_d      1.575      0.25     -40    42
# Comp:  2           [NII]6583_d      38.37      0.25     -40    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22        72
#  comp.  1:       -35        35
#  comp.  2:       -35        43
# chi2/DOF: 2.427; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.58      0.20     -35    35
# Comp:  1                 Hbeta      49.71      0.20     -35    35
# Comp:  1                Halpha      138.0      0.20     -35    35
# Comp:  2             [SII]6716      11.83      0.20     -35    43
# Comp:  2             [SII]6731      10.28      0.20     -35    43
# Comp:  2              HeII4687     0.3597      0.20     -35    43
# Comp:  2               HeI5876      5.613      0.20     -35    43
# Comp:  2          [OIII]5007_d      74.08      0.25     -35    43
# Comp:  2            [OI]6300_d      1.805      0.25     -35    43
# Comp:  2           [NII]6583_d      39.92      0.25     -35    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       362      1000
#  comp.  1:       -34        30
#  comp.  2:       -37        39
# chi2/DOF: 2.565; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.09      0.19     -34    30
# Comp:  1                 Hbeta      42.63      0.19     -34    30
# Comp:  1                Halpha      137.4      0.19     -34    30
# Comp:  2             [SII]6716      13.54      0.20     -37    39
# Comp:  2             [SII]6731      11.98      0.20     -37    39
# Comp:  2              HeII4687     0.3901      0.20     -37    39
# Comp:  2               HeI5876      5.596      0.20     -37    39
# Comp:  2          [OIII]5007_d      66.41      0.25     -37    39
# Comp:  2            [OI]6300_d      1.827      0.25     -37    39
# Comp:  2           [NII]6583_d      39.98      0.25     -37    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      1819       105
#  comp.  1:       -37        30
#  comp.  2:       -33        25
# chi2/DOF: 2.325; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.72      0.19     -37    30
# Comp:  1                 Hbeta      37.52      0.19     -37    30
# Comp:  1                Halpha      139.5      0.19     -37    30
# Comp:  2             [SII]6716      12.28      0.19     -33    25
# Comp:  2             [SII]6731      10.78      0.19     -33    25
# Comp:  2              HeII4687     0.3123      0.19     -33    25
# Comp:  2               HeI5876      5.557      0.19     -33    25
# Comp:  2          [OIII]5007_d      69.34      0.24     -33    25
# Comp:  2            [OI]6300_d      1.668      0.24     -33    25
# Comp:  2           [NII]6583_d      38.69      0.24     -33    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       126       700
#  comp.  1:       -37        31
#  comp.  2:       -33        35
# chi2/DOF: 2.807; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.97      0.19     -37    31
# Comp:  1                 Hbeta      44.41      0.19     -37    31
# Comp:  1                Halpha      138.5      0.19     -37    31
# Comp:  2             [SII]6716      12.67      0.20     -33    35
# Comp:  2             [SII]6731      10.90      0.20     -33    35
# Comp:  2              HeII4687     0.4729      0.20     -33    35
# Comp:  2               HeI5876      5.814      0.20     -33    35
# Comp:  2          [OIII]5007_d      69.08      0.25     -33    35
# Comp:  2            [OI]6300_d      1.556      0.25     -33    35
# Comp:  2           [NII]6583_d      40.59      0.25     -33    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       624      1000
#  comp.  1:       -36        28
#  comp.  2:       -30        40
# chi2/DOF: 2.545; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.30      0.19     -36    28
# Comp:  1                 Hbeta      45.42      0.19     -36    28
# Comp:  1                Halpha      138.9      0.19     -36    28
# Comp:  2             [SII]6716      14.33      0.20     -30    40
# Comp:  2             [SII]6731      10.21      0.20     -30    40
# Comp:  2              HeII4687     0.5471      0.20     -30    40
# Comp:  2               HeI5876      5.906      0.20     -30    40
# Comp:  2          [OIII]5007_d      75.14      0.25     -30    40
# Comp:  2            [OI]6300_d      1.541      0.25     -30    40
# Comp:  2           [NII]6583_d      39.39      0.25     -30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       229       665
#  comp.  1:       -37        28
#  comp.  2:       -38        40
# chi2/DOF: 2.417; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.42      0.19     -37    28
# Comp:  1                 Hbeta      39.03      0.19     -37    28
# Comp:  1                Halpha      139.0      0.19     -37    28
# Comp:  2             [SII]6716      11.84      0.20     -38    40
# Comp:  2             [SII]6731      11.18      0.20     -38    40
# Comp:  2              HeII4687     0.4143      0.20     -38    40
# Comp:  2               HeI5876      5.140      0.20     -38    40
# Comp:  2          [OIII]5007_d      68.50      0.25     -38    40
# Comp:  2            [OI]6300_d      1.568      0.25     -38    40
# Comp:  2           [NII]6583_d      41.88      0.25     -38    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       570       646
#  comp.  1:       -38        36
#  comp.  2:       -37        35
# chi2/DOF: 2.473; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.12      0.20     -38    36
# Comp:  1                 Hbeta      40.65      0.20     -38    36
# Comp:  1                Halpha      140.7      0.20     -38    36
# Comp:  2             [SII]6716      14.09      0.20     -37    35
# Comp:  2             [SII]6731      9.990      0.20     -37    35
# Comp:  2              HeII4687     0.4134      0.20     -37    35
# Comp:  2               HeI5876      5.552      0.20     -37    35
# Comp:  2          [OIII]5007_d      73.47      0.25     -37    35
# Comp:  2            [OI]6300_d      1.580      0.25     -37    35
# Comp:  2           [NII]6583_d      40.60      0.25     -37    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67       424
#  comp.  1:       -35        37
#  comp.  2:       -31        37
# chi2/DOF: 2.809; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.44      0.20     -35    37
# Comp:  1                 Hbeta      43.65      0.20     -35    37
# Comp:  1                Halpha      138.4      0.20     -35    37
# Comp:  2             [SII]6716      13.08      0.20     -31    37
# Comp:  2             [SII]6731      11.56      0.20     -31    37
# Comp:  2              HeII4687     0.4330      0.20     -31    37
# Comp:  2               HeI5876      5.609      0.20     -31    37
# Comp:  2          [OIII]5007_d      70.67      0.25     -31    37
# Comp:  2            [OI]6300_d      1.646      0.25     -31    37
# Comp:  2           [NII]6583_d      39.05      0.25     -31    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       544       977
#  comp.  1:       -34        31
#  comp.  2:       -31        47
# chi2/DOF: 2.562; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.99      0.19     -34    31
# Comp:  1                 Hbeta      41.10      0.19     -34    31
# Comp:  1                Halpha      137.2      0.19     -34    31
# Comp:  2             [SII]6716      14.82      0.20     -31    47
# Comp:  2             [SII]6731      11.27      0.20     -31    47
# Comp:  2              HeII4687     0.6044      0.20     -31    47
# Comp:  2               HeI5876      4.867      0.20     -31    47
# Comp:  2          [OIII]5007_d      75.88      0.26     -31    47
# Comp:  2            [OI]6300_d      1.790      0.26     -31    47
# Comp:  2           [NII]6583_d      39.37      0.26     -31    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       705       460
#  comp.  1:       -36        36
#  comp.  2:       -33        36
# chi2/DOF: 2.789; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.63      0.20     -36    36
# Comp:  1                 Hbeta      40.84      0.20     -36    36
# Comp:  1                Halpha      140.1      0.20     -36    36
# Comp:  2             [SII]6716      11.72      0.20     -33    36
# Comp:  2             [SII]6731      10.68      0.20     -33    36
# Comp:  2              HeII4687     0.5838      0.20     -33    36
# Comp:  2               HeI5876      5.334      0.20     -33    36
# Comp:  2          [OIII]5007_d      70.64      0.25     -33    36
# Comp:  2            [OI]6300_d      1.604      0.25     -33    36
# Comp:  2           [NII]6583_d      39.27      0.25     -33    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       408       862
#  comp.  1:       -35        29
#  comp.  2:       -29        50
# chi2/DOF: 2.635; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.01      0.19     -35    29
# Comp:  1                 Hbeta      43.13      0.19     -35    29
# Comp:  1                Halpha      136.4      0.19     -35    29
# Comp:  2             [SII]6716      14.66      0.21     -29    50
# Comp:  2             [SII]6731      11.53      0.21     -29    50
# Comp:  2              HeII4687     0.3957      0.21     -29    50
# Comp:  2               HeI5876      5.155      0.21     -29    50
# Comp:  2          [OIII]5007_d      77.25      0.26     -29    50
# Comp:  2            [OI]6300_d      1.869      0.26     -29    50
# Comp:  2           [NII]6583_d      41.45      0.26     -29    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       282       792
#  comp.  1:       -34        33
#  comp.  2:       -29        40
# chi2/DOF: 2.704; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.06      0.19     -34    33
# Comp:  1                 Hbeta      42.98      0.19     -34    33
# Comp:  1                Halpha      135.8      0.19     -34    33
# Comp:  2             [SII]6716      11.81      0.20     -29    40
# Comp:  2             [SII]6731      12.24      0.20     -29    40
# Comp:  2              HeII4687     0.3295      0.20     -29    40
# Comp:  2               HeI5876      5.972      0.20     -29    40
# Comp:  2          [OIII]5007_d      72.36      0.25     -29    40
# Comp:  2            [OI]6300_d      1.765      0.25     -29    40
# Comp:  2           [NII]6583_d      40.72      0.25     -29    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -35        36
#  comp.  2:       -31        46
# chi2/DOF: 2.466; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.71      0.20     -35    36
# Comp:  1                 Hbeta      48.85      0.20     -35    36
# Comp:  1                Halpha      138.5      0.20     -35    36
# Comp:  2             [SII]6716      14.28      0.20     -31    46
# Comp:  2             [SII]6731      10.14      0.20     -31    46
# Comp:  2              HeII4687     0.5018      0.20     -31    46
# Comp:  2               HeI5876      5.803      0.20     -31    46
# Comp:  2          [OIII]5007_d      71.15      0.26     -31    46
# Comp:  2            [OI]6300_d      1.820      0.26     -31    46
# Comp:  2           [NII]6583_d      41.16      0.26     -31    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       188       684
#  comp.  1:       -34        31
#  comp.  2:       -32        41
# chi2/DOF: 2.255; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.48      0.19     -34    31
# Comp:  1                 Hbeta      48.88      0.19     -34    31
# Comp:  1                Halpha      137.6      0.19     -34    31
# Comp:  2             [SII]6716      12.45      0.20     -32    41
# Comp:  2             [SII]6731      11.35      0.20     -32    41
# Comp:  2              HeII4687     0.4668      0.20     -32    41
# Comp:  2               HeI5876      6.048      0.20     -32    41
# Comp:  2          [OIII]5007_d      77.32      0.25     -32    41
# Comp:  2            [OI]6300_d      1.736      0.25     -32    41
# Comp:  2           [NII]6583_d      41.86      0.25     -32    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      1423       427
#  comp.  1:       -37        36
#  comp.  2:       -36        49
# chi2/DOF: 2.564; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.27      0.20     -37    36
# Comp:  1                 Hbeta      41.70      0.20     -37    36
# Comp:  1                Halpha      142.4      0.20     -37    36
# Comp:  2             [SII]6716      14.61      0.20     -36    49
# Comp:  2             [SII]6731      12.41      0.20     -36    49
# Comp:  2              HeII4687     0.4704      0.20     -36    49
# Comp:  2               HeI5876      5.727      0.20     -36    49
# Comp:  2          [OIII]5007_d      76.51      0.26     -36    49
# Comp:  2            [OI]6300_d      1.763      0.26     -36    49
# Comp:  2           [NII]6583_d      41.92      0.26     -36    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -130         1
#  comp.  1:       -35        36
#  comp.  2:       -40        44
# chi2/DOF: 2.257; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.37      0.20     -35    36
# Comp:  1                 Hbeta      49.63      0.20     -35    36
# Comp:  1                Halpha      138.4      0.20     -35    36
# Comp:  2             [SII]6716      11.98      0.20     -40    44
# Comp:  2             [SII]6731      11.50      0.20     -40    44
# Comp:  2              HeII4687     0.2709      0.20     -40    44
# Comp:  2               HeI5876      4.994      0.20     -40    44
# Comp:  2          [OIII]5007_d      69.30      0.25     -40    44
# Comp:  2            [OI]6300_d      1.867      0.25     -40    44
# Comp:  2           [NII]6583_d      40.73      0.25     -40    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       221       754
#  comp.  1:       -35        34
#  comp.  2:       -37        30
# chi2/DOF: 2.598; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.23      0.19     -35    34
# Comp:  1                 Hbeta      43.23      0.19     -35    34
# Comp:  1                Halpha      136.7      0.19     -35    34
# Comp:  2             [SII]6716      12.11      0.19     -37    30
# Comp:  2             [SII]6731      11.81      0.19     -37    30
# Comp:  2              HeII4687     0.3815      0.19     -37    30
# Comp:  2               HeI5876      5.050      0.19     -37    30
# Comp:  2          [OIII]5007_d      72.69      0.24     -37    30
# Comp:  2            [OI]6300_d      1.690      0.24     -37    30
# Comp:  2           [NII]6583_d      38.98      0.24     -37    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44         1
#  comp.  1:       -34        28
#  comp.  2:       -32        47
# chi2/DOF: 2.652; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.06      0.19     -34    28
# Comp:  1                 Hbeta      43.71      0.19     -34    28
# Comp:  1                Halpha      137.1      0.19     -34    28
# Comp:  2             [SII]6716      13.81      0.20     -32    47
# Comp:  2             [SII]6731      11.69      0.20     -32    47
# Comp:  2              HeII4687     0.2851      0.20     -32    47
# Comp:  2               HeI5876      5.321      0.20     -32    47
# Comp:  2          [OIII]5007_d      74.23      0.26     -32    47
# Comp:  2            [OI]6300_d      1.662      0.26     -32    47
# Comp:  2           [NII]6583_d      41.71      0.26     -32    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       371      1000
#  comp.  1:       -34        33
#  comp.  2:       -35        31
# chi2/DOF: 2.194; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.59      0.19     -34    33
# Comp:  1                 Hbeta      37.75      0.19     -34    33
# Comp:  1                Halpha      136.6      0.19     -34    33
# Comp:  2             [SII]6716      13.11      0.19     -35    31
# Comp:  2             [SII]6731      9.929      0.19     -35    31
# Comp:  2              HeII4687     0.3784      0.19     -35    31
# Comp:  2               HeI5876      5.047      0.19     -35    31
# Comp:  2          [OIII]5007_d      71.12      0.24     -35    31
# Comp:  2            [OI]6300_d      1.589      0.24     -35    31
# Comp:  2           [NII]6583_d      40.13      0.24     -35    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       528      1000
#  comp.  1:       -38        31
#  comp.  2:       -30        41
# chi2/DOF: 2.441; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.46      0.19     -38    31
# Comp:  1                 Hbeta      45.04      0.19     -38    31
# Comp:  1                Halpha      138.1      0.19     -38    31
# Comp:  2             [SII]6716      14.39      0.20     -30    41
# Comp:  2             [SII]6731      12.01      0.20     -30    41
# Comp:  2              HeII4687     0.4599      0.20     -30    41
# Comp:  2               HeI5876      5.236      0.20     -30    41
# Comp:  2          [OIII]5007_d      76.93      0.25     -30    41
# Comp:  2            [OI]6300_d      1.693      0.25     -30    41
# Comp:  2           [NII]6583_d      39.50      0.25     -30    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      1946      1000
#  comp.  1:       -36        33
#  comp.  2:       -33        32
# chi2/DOF: 2.463; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.96      0.19     -36    33
# Comp:  1                 Hbeta      37.47      0.19     -36    33
# Comp:  1                Halpha      139.2      0.19     -36    33
# Comp:  2             [SII]6716      11.53      0.19     -33    32
# Comp:  2             [SII]6731      11.92      0.19     -33    32
# Comp:  2              HeII4687     0.5860      0.19     -33    32
# Comp:  2               HeI5876      4.978      0.19     -33    32
# Comp:  2          [OIII]5007_d      70.80      0.24     -33    32
# Comp:  2            [OI]6300_d      1.610      0.24     -33    32
# Comp:  2           [NII]6583_d      38.70      0.24     -33    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141       992
#  comp.  1:       -37        38
#  comp.  2:       -28        42
# chi2/DOF: 2.622; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.74      0.20     -37    38
# Comp:  1                 Hbeta      44.80      0.20     -37    38
# Comp:  1                Halpha      141.8      0.20     -37    38
# Comp:  2             [SII]6716      12.97      0.20     -28    42
# Comp:  2             [SII]6731      10.88      0.20     -28    42
# Comp:  2              HeII4687     0.5069      0.20     -28    42
# Comp:  2               HeI5876      5.376      0.20     -28    42
# Comp:  2          [OIII]5007_d      68.30      0.25     -28    42
# Comp:  2            [OI]6300_d      1.597      0.25     -28    42
# Comp:  2           [NII]6583_d      40.42      0.25     -28    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       986         1
#  comp.  1:       -35        30
#  comp.  2:       -34        34
# chi2/DOF: 2.389; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 17; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.94      0.19     -35    30
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       205      1000
#  comp.  1:       -34        28
#  comp.  2:       -40        41
# chi2/DOF: 2.281; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.06      0.19     -34    28
# Comp:  1                 Hbeta      47.50      0.19     -34    28
# Comp:  1                Halpha      136.5      0.19     -34    28
# Comp:  2             [SII]6716      11.61      0.20     -40    41
# Comp:  2             [SII]6731      11.84      0.20     -40    41
# Comp:  2              HeII4687     0.4277      0.20     -40    41
# Comp:  2               HeI5876      5.701      0.20     -40    41
# Comp:  2          [OIII]5007_d      71.75      0.25     -40    41
# Comp:  2            [OI]6300_d      1.632      0.25     -40    41
# Comp:  2           [NII]6583_d      42.04      0.25     -40    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20        66
#  comp.  1:       -34        29
#  comp.  2:       -32        47
# chi2/DOF: 2.618; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.75      0.19     -34    29
# Comp:  1                 Hbeta      41.83      0.19     -34    29
# Comp:  1                Halpha      137.1      0.19     -34    29
# Comp:  2             [SII]6716      12.84      0.20     -32    47
# Comp:  2             [SII]6731      11.08      0.20     -32    47
# Comp:  2              HeII4687     0.3450      0.20     -32    47
# Comp:  2               HeI5876      5.550      0.20     -32    47
# Comp:  2          [OIII]5007_d      73.39      0.26     -32    47
# Comp:  2            [OI]6300_d      1.851      0.26     -32    47
# Comp:  2           [NII]6583_d      43.41      0.26     -32    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:       -38        35
#  comp.  2:       -36        32
# chi2/DOF: 2.618; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.32      0.20     -38    35
# Comp:  1                 Hbeta      46.50      0.20     -38    35
# Comp:  1                Halpha      141.3      0.20     -38    35
# Comp:  2             [SII]6716      13.70      0.19     -36    32
# Comp:  2             [SII]6731      10.85      0.19     -36    32
# Comp:  2              HeII4687     0.4508      0.19     -36    32
# Comp:  2               HeI5876      5.867      0.19     -36    32
# Comp:  2          [OIII]5007_d      68.17      0.24     -36    32
# Comp:  2            [OI]6300_d      1.611      0.24     -36    32
# Comp:  2           [NII]6583_d      40.04      0.24     -36    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       238      1000
#  comp.  1:       -36        31
#  comp.  2:       -34        35
# chi2/DOF: 2.544; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.26      0.19     -36    31
# Comp:  1                 Hbeta      37.98      0.19     -36    31
# Comp:  1                Halpha      140.6      0.19     -36    31
# Comp:  2             [SII]6716      12.61      0.20     -34    35
# Comp:  2             [SII]6731      10.57      0.20     -34    35
# Comp:  2              HeII4687     0.3482      0.20     -34    35
# Comp:  2               HeI5876      5.324      0.20     -34    35
# Comp:  2          [OIII]5007_d      69.92      0.25     -34    35
# Comp:  2            [OI]6300_d      1.683      0.25     -34    35
# Comp:  2           [NII]6583_d      38.14      0.25     -34    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       453       855
#  comp.  1:       -36        37
#  comp.  2:       -30        44
# chi2/DOF: 2.622; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.67      0.20     -36    37
# Comp:  1                 Hbeta      41.52      0.20     -36    37
# Comp:  1                Halpha      141.6      0.20     -36    37
# Comp:  2             [SII]6716      11.68      0.20     -30    44
# Comp:  2             [SII]6731      12.25      0.20     -30    44
# Comp:  2              HeII4687     0.3059      0.20     -30    44
# Comp:  2               HeI5876      5.782      0.20     -30    44
# Comp:  2          [OIII]5007_d      75.40      0.25     -30    44
# Comp:  2            [OI]6300_d      1.625      0.25     -30    44
# Comp:  2           [NII]6583_d      39.65      0.25     -30    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       240       819
#  comp.  1:       -37        36
#  comp.  2:       -31        28
# chi2/DOF: 2.503; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.87      0.20     -37    36
# Comp:  1                 Hbeta      43.69      0.20     -37    36
# Comp:  1                Halpha      140.5      0.20     -37    36
# Comp:  2             [SII]6716      13.69      0.19     -31    28
# Comp:  2             [SII]6731      11.52      0.19     -31    28
# Comp:  2              HeII4687     0.3298      0.19     -31    28
# Comp:  2               HeI5876      5.444      0.19     -31    28
# Comp:  2          [OIII]5007_d      70.43      0.24     -31    28
# Comp:  2            [OI]6300_d      1.591      0.24     -31    28
# Comp:  2           [NII]6583_d      38.23      0.24     -31    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       374      1000
#  comp.  1:       -37        32
#  comp.  2:       -28        45
# chi2/DOF: 2.542; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.91      0.19     -37    32
# Comp:  1                 Hbeta      41.75      0.19     -37    32
# Comp:  1                Halpha      138.6      0.19     -37    32
# Comp:  2             [SII]6716      14.73      0.20     -28    45
# Comp:  2             [SII]6731      11.55      0.20     -28    45
# Comp:  2              HeII4687     0.3957      0.20     -28    45
# Comp:  2               HeI5876      5.548      0.20     -28    45
# Comp:  2          [OIII]5007_d      69.70      0.25     -28    45
# Comp:  2            [OI]6300_d      1.718      0.25     -28    45
# Comp:  2           [NII]6583_d      40.56      0.25     -28    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        80         1
#  comp.  1:       -35        36
#  comp.  2:       -29        44
# chi2/DOF: 2.750; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.16      0.20     -35    36
# Comp:  1                 Hbeta      44.72      0.20     -35    36
# Comp:  1                Halpha      140.4      0.20     -35    36
# Comp:  2             [SII]6716      12.91      0.20     -29    44
# Comp:  2             [SII]6731      12.24      0.20     -29    44
# Comp:  2              HeII4687     0.4185      0.20     -29    44
# Comp:  2               HeI5876      5.235      0.20     -29    44
# Comp:  2          [OIII]5007_d      69.98      0.25     -29    44
# Comp:  2            [OI]6300_d      1.714      0.25     -29    44
# Comp:  2           [NII]6583_d      41.11      0.25     -29    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      2276      1000
#  comp.  1:       -36        35
#  comp.  2:       -38        36
# chi2/DOF: 2.610; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.31      0.20     -36    35
# Comp:  1                 Hbeta      41.73      0.20     -36    35
# Comp:  1                Halpha      142.8      0.20     -36    35
# Comp:  2             [SII]6716      12.32      0.20     -38    36
# Comp:  2             [SII]6731      11.06      0.20     -38    36
# Comp:  2              HeII4687     0.4322      0.20     -38    36
# Comp:  2               HeI5876      5.620      0.20     -38    36
# Comp:  2          [OIII]5007_d      73.94      0.25     -38    36
# Comp:  2            [OI]6300_d      1.689      0.25     -38    36
# Comp:  2           [NII]6583_d      40.22      0.25     -38    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       138      1000
#  comp.  1:       -36        34
#  comp.  2:       -32        41
# chi2/DOF: 2.831; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.31      0.19     -36    34
# Comp:  1                 Hbeta      43.80      0.19     -36    34
# Comp:  1                Halpha      140.0      0.19     -36    34
# Comp:  2             [SII]6716      13.25      0.20     -32    41
# Comp:  2             [SII]6731      12.35      0.20     -32    41
# Comp:  2              HeII4687     0.3691      0.20     -32    41
# Comp:  2               HeI5876      5.705      0.20     -32    41
# Comp:  2          [OIII]5007_d      71.64      0.25     -32    41
# Comp:  2            [OI]6300_d      1.712      0.25     -32    41
# Comp:  2           [NII]6583_d      42.46      0.25     -32    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      1006      1000
#  comp.  1:       -35        34
#  comp.  2:       -30        41
# chi2/DOF: 2.784; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.32      0.19     -35    34
# Comp:  1                 Hbeta      41.40      0.19     -35    34
# Comp:  1                Halpha      138.7      0.19     -35    34
# Comp:  2             [SII]6716      11.64      0.20     -30    41
# Comp:  2             [SII]6731      10.87      0.20     -30    41
# Comp:  2              HeII4687     0.4872      0.20     -30    41
# Comp:  2               HeI5876      5.940      0.20     -30    41
# Comp:  2          [OIII]5007_d      72.11      0.25     -30    41
# Comp:  2            [OI]6300_d      1.554      0.25     -30    41
# Comp:  2           [NII]6583_d      41.75      0.25     -30    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       928      1000
#  comp.  1:       -37        30
#  comp.  2:       -32        42
# chi2/DOF: 2.693; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.95      0.19     -37    30
# Comp:  1                 Hbeta      45.23      0.19     -37    30
# Comp:  1                Halpha      140.4      0.19     -37    30
# Comp:  2             [SII]6716      14.35      0.20     -32    42
# Comp:  2             [SII]6731      11.19      0.20     -32    42
# Comp:  2              HeII4687     0.5474      0.20     -32    42
# Comp:  2               HeI5876      5.068      0.20     -32    42
# Comp:  2          [OIII]5007_d      72.15      0.25     -32    42
# Comp:  2            [OI]6300_d      1.725      0.25     -32    42
# Comp:  2           [NII]6583_d      38.97      0.25     -32    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72      1000
#  comp.  1:       -38        37
#  comp.  2:       -35        31
# chi2/DOF: 2.497; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.44      0.20     -38    37
# Comp:  1                 Hbeta      40.86      0.20     -38    37
# Comp:  1                Halpha      140.9      0.20     -38    37
# Comp:  2             [SII]6716      12.90      0.19     -35    31
# Comp:  2             [SII]6731      9.880      0.19     -35    31
# Comp:  2              HeII4687     0.4861      0.19     -35    31
# Comp:  2               HeI5876      5.025      0.19     -35    31
# Comp:  2          [OIII]5007_d      67.46      0.24     -35    31
# Comp:  2            [OI]6300_d      1.659      0.24     -35    31
# Comp:  2           [NII]6583_d      38.94      0.24     -35    31
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.8480093 , 3.43657316, 2.69632297, 1.35912001, 0.95908589,
#        0.07616363, 0.51215136, 3.47840951, 0.12779109, 1.77187567])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 16.84605347,  43.8642845 , 189.99217473,  18.20456741,
#         15.61363228,   0.45621976,   6.75339378,  75.00094408,
#          2.21059832,  55.57877231])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   8.370190    0.918208
# 1         Hbeta  21.794563    1.707508
# 2        Halpha  94.400183    1.339705
# 3     [SII]6716   9.045186    0.675297
# 4     [SII]6731   7.757844    0.476535
# 5      HeII4687   0.226679    0.037843
# 6       HeI5876   3.355515    0.254469
# 7  [OIII]5007_d  37.265234    1.728295
# 8    [OI]6300_d   1.098366    0.063495
# 9   [NII]6583_d  27.615065    0.880380
#           Name       Flux  Error_flux
# 0       Hgamma   8.370190    0.918208
# 1        Hbeta  21.794563    1.707508
# 2       Halpha  94.400183    1.339705
# 3    [SII]6716   9.045186    0.675297
# 4    [SII]6731   7.757844    0.476535
# 5     HeII4687   0.226679    0.037843
# 6      HeI5876   3.355515    0.254469
# 7   [OIII]4959   9.316308    1.728295
# 8   [OIII]5007  27.948925    1.728295
# 9     [OI]6300   0.823774    0.063495
# 10    [OI]6364   0.274591    0.063495
# 11   [NII]6548   6.903766    0.880380
# 12   [NII]6583  20.711299    0.880380

# %%
np.median(flux_rf_rebin)
# Out:
# 0.49686353025352004
