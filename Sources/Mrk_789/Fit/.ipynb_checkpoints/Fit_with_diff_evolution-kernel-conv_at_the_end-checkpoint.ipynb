# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32

# %%
image_cut = image[75:175, 0:1890]
image_error_cut = image_error[75:175, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.03144
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/PSF/Real_seeing_Mrk789.txt")
sigmas = seeing / 2.35
n_component = 3
print(sigmas)
# Out:
# [0.81079758 0.94529828 0.80761288 0.78693189 0.94913518 0.84425532]

# %%
l_HA
# Out:
# 6769.340719999999

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[75:175, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 24)*(y < 34)
mask_wv = wv > 4451
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Propagazione_errore/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 110)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 110)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 100),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 43),   # x_0: posizione da 0 a 100

    (0, 20),
    (0, 50),
    (0.1, 10),
    (46, 50),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (54, 61)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 17231.75084099845
# differential_evolution step 2: f(x)= 17231.75084099845
# differential_evolution step 3: f(x)= 10783.882777507843
# differential_evolution step 4: f(x)= 10783.882777507843
# differential_evolution step 5: f(x)= 9445.51473450423
# differential_evolution step 6: f(x)= 9445.51473450423
# differential_evolution step 7: f(x)= 9445.51473450423
# differential_evolution step 8: f(x)= 9445.51473450423
# differential_evolution step 9: f(x)= 9445.51473450423
# differential_evolution step 10: f(x)= 4042.2169895951533
# differential_evolution step 11: f(x)= 4042.2169895951533
# differential_evolution step 12: f(x)= 3335.3439746389686
# differential_evolution step 13: f(x)= 3335.3439746389686
# differential_evolution step 14: f(x)= 3335.3439746389686
# differential_evolution step 15: f(x)= 3335.3439746389686
# differential_evolution step 16: f(x)= 3335.3439746389686
# differential_evolution step 17: f(x)= 3335.3439746389686
# differential_evolution step 18: f(x)= 3335.3439746389686
# differential_evolution step 19: f(x)= 3335.3439746389686
# differential_evolution step 20: f(x)= 3335.3439746389686
# differential_evolution step 21: f(x)= 3335.3439746389686
# differential_evolution step 22: f(x)= 3335.3439746389686
# differential_evolution step 23: f(x)= 2227.305700111202
# differential_evolution step 24: f(x)= 2146.781785483096
# differential_evolution step 25: f(x)= 1917.4945336123421
# differential_evolution step 26: f(x)= 1917.4945336123421
# differential_evolution step 27: f(x)= 1917.4945336123421
# differential_evolution step 28: f(x)= 1917.4945336123421
# differential_evolution step 29: f(x)= 1917.4945336123421
# differential_evolution step 30: f(x)= 1311.6283773825078
# differential_evolution step 31: f(x)= 1311.6283773825078
# differential_evolution step 32: f(x)= 1311.6283773825078
# differential_evolution step 33: f(x)= 1298.008898639938
# differential_evolution step 34: f(x)= 1298.008898639938
# differential_evolution step 35: f(x)= 1292.6750503121102
# differential_evolution step 36: f(x)= 1094.8790429282697
# differential_evolution step 37: f(x)= 1094.8790429282697
# differential_evolution step 38: f(x)= 970.9947625191074
# differential_evolution step 39: f(x)= 970.9947625191074
# differential_evolution step 40: f(x)= 970.9947625191074
# differential_evolution step 41: f(x)= 875.1227343272228
# differential_evolution step 42: f(x)= 875.1227343272228
# differential_evolution step 43: f(x)= 875.1227343272228
# differential_evolution step 44: f(x)= 875.1227343272228
# differential_evolution step 45: f(x)= 819.3133995130473
# differential_evolution step 46: f(x)= 819.3133995130473
# differential_evolution step 47: f(x)= 568.6945082242421
# differential_evolution step 48: f(x)= 568.6945082242421
# differential_evolution step 49: f(x)= 568.6945082242421
# differential_evolution step 50: f(x)= 568.6945082242421
# differential_evolution step 51: f(x)= 568.6945082242421
# differential_evolution step 52: f(x)= 568.6945082242421
# differential_evolution step 53: f(x)= 402.5959733009394
# differential_evolution step 54: f(x)= 348.16957444350794
# differential_evolution step 55: f(x)= 348.16957444350794
# differential_evolution step 56: f(x)= 348.16957444350794
# differential_evolution step 57: f(x)= 348.16957444350794
# differential_evolution step 58: f(x)= 348.16957444350794
# differential_evolution step 59: f(x)= 348.16957444350794
# differential_evolution step 60: f(x)= 348.16957444350794
# differential_evolution step 61: f(x)= 348.16957444350794
# differential_evolution step 62: f(x)= 348.16957444350794
# differential_evolution step 63: f(x)= 348.16957444350794
# differential_evolution step 64: f(x)= 348.16957444350794
# differential_evolution step 65: f(x)= 348.16957444350794
# differential_evolution step 66: f(x)= 338.6785575025911
# differential_evolution step 67: f(x)= 338.6785575025911
# differential_evolution step 68: f(x)= 326.98453247277223
# differential_evolution step 69: f(x)= 264.8101540793562
# differential_evolution step 70: f(x)= 264.8101540793562
# differential_evolution step 71: f(x)= 203.16723503982158
# differential_evolution step 72: f(x)= 188.11265029965574
# differential_evolution step 73: f(x)= 138.2892210488549
# differential_evolution step 74: f(x)= 138.2892210488549
# differential_evolution step 75: f(x)= 138.2892210488549
# differential_evolution step 76: f(x)= 138.2892210488549
# differential_evolution step 77: f(x)= 138.2892210488549
# differential_evolution step 78: f(x)= 138.2892210488549
# differential_evolution step 79: f(x)= 138.2892210488549
# differential_evolution step 80: f(x)= 138.2892210488549
# differential_evolution step 81: f(x)= 138.2892210488549
# differential_evolution step 82: f(x)= 138.2892210488549
# differential_evolution step 83: f(x)= 138.2892210488549
# differential_evolution step 84: f(x)= 138.2892210488549
# differential_evolution step 85: f(x)= 138.2892210488549
# differential_evolution step 86: f(x)= 138.2892210488549
# differential_evolution step 87: f(x)= 130.0376184914273
# differential_evolution step 88: f(x)= 130.0376184914273
# differential_evolution step 89: f(x)= 130.0376184914273
# differential_evolution step 90: f(x)= 130.0376184914273
# differential_evolution step 91: f(x)= 130.0376184914273
# differential_evolution step 92: f(x)= 130.0376184914273
# differential_evolution step 93: f(x)= 130.0376184914273
# differential_evolution step 94: f(x)= 101.5959454006954
# differential_evolution step 95: f(x)= 101.5959454006954
# differential_evolution step 96: f(x)= 101.5959454006954
# differential_evolution step 97: f(x)= 101.5959454006954
# differential_evolution step 98: f(x)= 101.5959454006954
# differential_evolution step 99: f(x)= 101.5959454006954
# differential_evolution step 100: f(x)= 95.22081069905941
# differential_evolution step 101: f(x)= 95.22081069905941
# differential_evolution step 102: f(x)= 95.22081069905941
# differential_evolution step 103: f(x)= 95.22081069905941
# differential_evolution step 104: f(x)= 95.22081069905941
# differential_evolution step 105: f(x)= 93.52210514379779
# differential_evolution step 106: f(x)= 93.52210514379779
# differential_evolution step 107: f(x)= 93.52210514379779
# differential_evolution step 108: f(x)= 91.9657596183109
# differential_evolution step 109: f(x)= 87.1204249541395
# differential_evolution step 110: f(x)= 87.1204249541395
# differential_evolution step 111: f(x)= 87.1204249541395
# differential_evolution step 112: f(x)= 84.83003967391416
# differential_evolution step 113: f(x)= 84.83003967391416
# differential_evolution step 114: f(x)= 84.83003967391416
# differential_evolution step 115: f(x)= 84.83003967391416
# differential_evolution step 116: f(x)= 84.83003967391416
# differential_evolution step 117: f(x)= 84.83003967391416
# differential_evolution step 118: f(x)= 84.83003967391416
# differential_evolution step 119: f(x)= 84.30032933073744
# differential_evolution step 120: f(x)= 84.30032933073744
# differential_evolution step 121: f(x)= 80.57521758523913
# differential_evolution step 122: f(x)= 80.57521758523913
# differential_evolution step 123: f(x)= 80.57521758523913
# differential_evolution step 124: f(x)= 80.57521758523913
# differential_evolution step 125: f(x)= 80.57521758523913
# differential_evolution step 126: f(x)= 80.57521758523913
# differential_evolution step 127: f(x)= 80.57521758523913
# differential_evolution step 128: f(x)= 80.57521758523913
# differential_evolution step 129: f(x)= 80.57521758523913
# differential_evolution step 130: f(x)= 80.57521758523913
# differential_evolution step 131: f(x)= 80.57521758523913
# differential_evolution step 132: f(x)= 80.57521758523913
# differential_evolution step 133: f(x)= 80.57521758523913
# differential_evolution step 134: f(x)= 80.57521758523913
# differential_evolution step 135: f(x)= 79.54567238038733
# differential_evolution step 136: f(x)= 79.54567238038733
# differential_evolution step 137: f(x)= 79.54567238038733
# differential_evolution step 138: f(x)= 79.54567238038733
# differential_evolution step 139: f(x)= 79.54567238038733
# differential_evolution step 140: f(x)= 79.54567238038733
# differential_evolution step 141: f(x)= 79.54567238038733
# differential_evolution step 142: f(x)= 79.54567238038733
# differential_evolution step 143: f(x)= 78.48933538065438
# differential_evolution step 144: f(x)= 78.48933538065438
# differential_evolution step 145: f(x)= 77.14389127804893
# differential_evolution step 146: f(x)= 77.14389127804893
# differential_evolution step 147: f(x)= 77.14389127804893
# differential_evolution step 148: f(x)= 75.31607952871066
# differential_evolution step 149: f(x)= 75.31607952871066
# differential_evolution step 150: f(x)= 74.5271232721835
# differential_evolution step 151: f(x)= 74.5271232721835
# differential_evolution step 152: f(x)= 74.5271232721835
# differential_evolution step 153: f(x)= 74.5271232721835
# differential_evolution step 154: f(x)= 74.5271232721835
# differential_evolution step 155: f(x)= 74.5271232721835
# differential_evolution step 156: f(x)= 74.5271232721835
# differential_evolution step 157: f(x)= 73.66419360364057
# differential_evolution step 158: f(x)= 73.66419360364057
# differential_evolution step 159: f(x)= 73.66419360364057
# differential_evolution step 160: f(x)= 73.66419360364057
# differential_evolution step 161: f(x)= 72.60811802020875
# differential_evolution step 162: f(x)= 72.60811802020875
# differential_evolution step 163: f(x)= 72.60811802020875
# differential_evolution step 164: f(x)= 72.60811802020875
# differential_evolution step 165: f(x)= 72.60811802020875
# differential_evolution step 166: f(x)= 72.60811802020875
# differential_evolution step 167: f(x)= 72.60811802020875
# differential_evolution step 168: f(x)= 70.34350769426689
# differential_evolution step 169: f(x)= 70.34350769426689
# differential_evolution step 170: f(x)= 70.34350769426689
# differential_evolution step 171: f(x)= 70.34350769426689
# differential_evolution step 172: f(x)= 70.34350769426689
# differential_evolution step 173: f(x)= 70.34350769426689
# differential_evolution step 174: f(x)= 70.34350769426689
# differential_evolution step 175: f(x)= 70.34350769426689
# differential_evolution step 176: f(x)= 70.34350769426689
# differential_evolution step 177: f(x)= 70.34350769426689
# differential_evolution step 178: f(x)= 70.34350769426689
# differential_evolution step 179: f(x)= 70.34350769426689
# differential_evolution step 180: f(x)= 70.34350769426689
# differential_evolution step 181: f(x)= 70.34350769426689
# differential_evolution step 182: f(x)= 70.34350769426689
# differential_evolution step 183: f(x)= 70.34350769426689
# differential_evolution step 184: f(x)= 70.34350769426689
# differential_evolution step 185: f(x)= 70.34350769426689
# differential_evolution step 186: f(x)= 70.34350769426689
# differential_evolution step 187: f(x)= 70.19666545118046
# differential_evolution step 188: f(x)= 70.19666545118046
# differential_evolution step 189: f(x)= 69.95004169457073
# differential_evolution step 190: f(x)= 69.95004169457073
# differential_evolution step 191: f(x)= 69.95004169457073
# differential_evolution step 192: f(x)= 69.95004169457073
# differential_evolution step 193: f(x)= 69.95004169457073
# differential_evolution step 194: f(x)= 69.95004169457073
# differential_evolution step 195: f(x)= 69.95004169457073
# differential_evolution step 196: f(x)= 69.820726100402
# differential_evolution step 197: f(x)= 69.76598532729889
# differential_evolution step 198: f(x)= 69.76598532729889
# differential_evolution step 199: f(x)= 69.76598532729889
# differential_evolution step 200: f(x)= 69.76598532729889
# differential_evolution step 201: f(x)= 69.67646390447668
# differential_evolution step 202: f(x)= 69.62459960509773
# differential_evolution step 203: f(x)= 69.62459960509773
# differential_evolution step 204: f(x)= 69.62459960509773
# differential_evolution step 205: f(x)= 69.62459960509773
# differential_evolution step 206: f(x)= 69.62459960509773
# differential_evolution step 207: f(x)= 69.62459960509773
# differential_evolution step 208: f(x)= 69.62459960509773
# differential_evolution step 209: f(x)= 69.62459960509773
# differential_evolution step 210: f(x)= 69.62459960509773
# differential_evolution step 211: f(x)= 69.62459960509773
# differential_evolution step 212: f(x)= 69.62459960509773
# differential_evolution step 213: f(x)= 69.62459960509773
# differential_evolution step 214: f(x)= 69.58903578275464
# differential_evolution step 215: f(x)= 69.58903578275464
# differential_evolution step 216: f(x)= 69.5146220560882
# differential_evolution step 217: f(x)= 69.5146220560882
# differential_evolution step 218: f(x)= 69.27285308612494
# differential_evolution step 219: f(x)= 69.27285308612494
# differential_evolution step 220: f(x)= 69.27285308612494
# differential_evolution step 221: f(x)= 69.27285308612494
# differential_evolution step 222: f(x)= 69.27285308612494
# differential_evolution step 223: f(x)= 69.27285308612494
# differential_evolution step 224: f(x)= 69.27285308612494
# differential_evolution step 225: f(x)= 69.27285308612494
# differential_evolution step 226: f(x)= 69.27285308612494
# differential_evolution step 227: f(x)= 69.27285308612494
# differential_evolution step 228: f(x)= 69.27285308612494
# differential_evolution step 229: f(x)= 69.27285308612494
# differential_evolution step 230: f(x)= 69.27285308612494
# differential_evolution step 231: f(x)= 69.27285308612494
# differential_evolution step 232: f(x)= 69.27285308612494
# differential_evolution step 233: f(x)= 69.27285308612494
# differential_evolution step 234: f(x)= 69.27285308612494
# differential_evolution step 235: f(x)= 69.27285308612494
# differential_evolution step 236: f(x)= 69.27285308612494
# differential_evolution step 237: f(x)= 69.27285308612494
# differential_evolution step 238: f(x)= 69.17683530114324
# differential_evolution step 239: f(x)= 69.17683530114324
# differential_evolution step 240: f(x)= 69.17683530114324
# differential_evolution step 241: f(x)= 69.17683530114324
# differential_evolution step 242: f(x)= 69.17683530114324
# differential_evolution step 243: f(x)= 69.17683530114324
# differential_evolution step 244: f(x)= 69.17683530114324
# differential_evolution step 245: f(x)= 69.17683530114324
# differential_evolution step 246: f(x)= 69.09241913507502
# differential_evolution step 247: f(x)= 69.09241913507502
# differential_evolution step 248: f(x)= 69.09241913507502
# differential_evolution step 249: f(x)= 69.09241913507502
# differential_evolution step 250: f(x)= 69.09241913507502
# differential_evolution step 251: f(x)= 68.99645074560476
# differential_evolution step 252: f(x)= 68.99645074560476
# differential_evolution step 253: f(x)= 68.99645074560476
# differential_evolution step 254: f(x)= 68.99645074560476
# differential_evolution step 255: f(x)= 68.95588959348039
# differential_evolution step 256: f(x)= 68.95588959348039
# differential_evolution step 257: f(x)= 68.94422240503768
# differential_evolution step 258: f(x)= 68.94422240503768
# differential_evolution step 259: f(x)= 68.94422240503768
# differential_evolution step 260: f(x)= 68.94422240503768
# differential_evolution step 261: f(x)= 68.94422240503768
# differential_evolution step 262: f(x)= 68.94422240503768
# differential_evolution step 263: f(x)= 68.94422240503768
# differential_evolution step 264: f(x)= 68.94422240503768
# differential_evolution step 265: f(x)= 68.94422240503768
# differential_evolution step 266: f(x)= 68.94422240503768
# differential_evolution step 267: f(x)= 68.94422240503768
# differential_evolution step 268: f(x)= 68.94422240503768
# differential_evolution step 269: f(x)= 68.94422240503768
# differential_evolution step 270: f(x)= 68.94422240503768
# differential_evolution step 271: f(x)= 68.94422240503768
# differential_evolution step 272: f(x)= 68.94422240503768
# differential_evolution step 273: f(x)= 68.94422240503768
# differential_evolution step 274: f(x)= 68.94422240503768
# differential_evolution step 275: f(x)= 68.94422240503768
# differential_evolution step 276: f(x)= 68.94422240503768
# differential_evolution step 277: f(x)= 68.92011939968498
# differential_evolution step 278: f(x)= 68.92011939968498
# differential_evolution step 279: f(x)= 68.9115316929431
# differential_evolution step 280: f(x)= 68.9115316929431
# differential_evolution step 281: f(x)= 68.9115316929431
# differential_evolution step 282: f(x)= 68.9115316929431
# differential_evolution step 283: f(x)= 68.9115316929431
# differential_evolution step 284: f(x)= 68.9115316929431
# differential_evolution step 285: f(x)= 68.9115316929431
# differential_evolution step 286: f(x)= 68.9115316929431
# differential_evolution step 287: f(x)= 68.84811311124729
# differential_evolution step 288: f(x)= 68.84811311124729
# differential_evolution step 289: f(x)= 68.81854710970889
# differential_evolution step 290: f(x)= 68.81854710970889
# differential_evolution step 291: f(x)= 68.80386466503231
# differential_evolution step 292: f(x)= 68.80386466503231
# differential_evolution step 293: f(x)= 68.80386466503231
# differential_evolution step 294: f(x)= 68.80386466503231
# differential_evolution step 295: f(x)= 68.80386466503231
# differential_evolution step 296: f(x)= 68.80265482705545
# differential_evolution step 297: f(x)= 68.80265482705545
# differential_evolution step 298: f(x)= 68.80265482705545
# differential_evolution step 299: f(x)= 68.80265482705545
# differential_evolution step 300: f(x)= 68.80265482705545
# differential_evolution step 301: f(x)= 68.80265482705545
# differential_evolution step 302: f(x)= 68.80265482705545
# differential_evolution step 303: f(x)= 68.80265482705545
# differential_evolution step 304: f(x)= 68.80265482705545
# differential_evolution step 305: f(x)= 68.80265482705545
# differential_evolution step 306: f(x)= 68.80265482705545
# differential_evolution step 307: f(x)= 68.80265482705545
# differential_evolution step 308: f(x)= 68.80265482705545
# differential_evolution step 309: f(x)= 68.80265482705545
# differential_evolution step 310: f(x)= 68.7935799311412
# differential_evolution step 311: f(x)= 68.7935799311412
# differential_evolution step 312: f(x)= 68.7935799311412
# differential_evolution step 313: f(x)= 68.7935799311412
# differential_evolution step 314: f(x)= 68.7935799311412
# differential_evolution step 315: f(x)= 68.7935799311412
# differential_evolution step 316: f(x)= 68.7935799311412
# differential_evolution step 317: f(x)= 68.7935799311412
# differential_evolution step 318: f(x)= 68.7935799311412
# differential_evolution step 319: f(x)= 68.7935799311412
# differential_evolution step 320: f(x)= 68.7935799311412
# differential_evolution step 321: f(x)= 68.7935799311412
# differential_evolution step 322: f(x)= 68.78948890564416
# differential_evolution step 323: f(x)= 68.78948890564416
# differential_evolution step 324: f(x)= 68.78948890564416
# differential_evolution step 325: f(x)= 68.78948890564416
# differential_evolution step 326: f(x)= 68.78948890564416
# differential_evolution step 327: f(x)= 68.7852703441586
# differential_evolution step 328: f(x)= 68.7852703441586
# differential_evolution step 329: f(x)= 68.7852703441586
# differential_evolution step 330: f(x)= 68.7852703441586
# differential_evolution step 331: f(x)= 68.7852703441586
# differential_evolution step 332: f(x)= 68.7852703441586
# differential_evolution step 333: f(x)= 68.7852703441586
# differential_evolution step 334: f(x)= 68.7852703441586
# differential_evolution step 335: f(x)= 68.7852703441586
# differential_evolution step 336: f(x)= 68.7852703441586
# differential_evolution step 337: f(x)= 68.7852703441586
# differential_evolution step 338: f(x)= 68.7852703441586
# differential_evolution step 339: f(x)= 68.7852703441586
# differential_evolution step 340: f(x)= 68.7852703441586
# differential_evolution step 341: f(x)= 68.7852703441586
# differential_evolution step 342: f(x)= 68.7852703441586
# differential_evolution step 343: f(x)= 68.7852703441586
# differential_evolution step 344: f(x)= 68.77011201083408
# differential_evolution step 345: f(x)= 68.77011201083408
# differential_evolution step 346: f(x)= 68.77011201083408
# differential_evolution step 347: f(x)= 68.77010683585019
# differential_evolution step 348: f(x)= 68.77010683585019
# differential_evolution step 349: f(x)= 68.77010683585019
# differential_evolution step 350: f(x)= 68.77010683585019
# differential_evolution step 351: f(x)= 68.77010683585019
# differential_evolution step 352: f(x)= 68.77010683585019
# differential_evolution step 353: f(x)= 68.77010683585019
# differential_evolution step 354: f(x)= 68.77010683585019
# differential_evolution step 355: f(x)= 68.77010683585019
# differential_evolution step 356: f(x)= 68.77010683585019
# differential_evolution step 357: f(x)= 68.76895846645466
# differential_evolution step 358: f(x)= 68.76895846645466
# differential_evolution step 359: f(x)= 68.76895846645466
# differential_evolution step 360: f(x)= 68.76895846645466
# differential_evolution step 361: f(x)= 68.75500393696312
# differential_evolution step 362: f(x)= 68.75500393696312
# differential_evolution step 363: f(x)= 68.75500393696312
# differential_evolution step 364: f(x)= 68.75500393696312
# differential_evolution step 365: f(x)= 68.75383797125995
# differential_evolution step 366: f(x)= 68.75383797125995
# differential_evolution step 367: f(x)= 68.74963941903987
# differential_evolution step 368: f(x)= 68.74963941903987
# differential_evolution step 369: f(x)= 68.74963941903987
# differential_evolution step 370: f(x)= 68.74963941903987
# differential_evolution step 371: f(x)= 68.74963941903987
# differential_evolution step 372: f(x)= 68.74963941903987
# differential_evolution step 373: f(x)= 68.74963941903987
# differential_evolution step 374: f(x)= 68.74963941903987
# differential_evolution step 375: f(x)= 68.74963941903987
# differential_evolution step 376: f(x)= 68.74963941903987
# differential_evolution step 377: f(x)= 68.74409619558413
# differential_evolution step 378: f(x)= 68.74409619558413
# differential_evolution step 379: f(x)= 68.74409619558413
# differential_evolution step 380: f(x)= 68.74409619558413
# differential_evolution step 381: f(x)= 68.74409619558413
# differential_evolution step 382: f(x)= 68.74409619558413
# differential_evolution step 383: f(x)= 68.74409619558413
# differential_evolution step 384: f(x)= 68.74409619558413
# differential_evolution step 385: f(x)= 68.74409619558413
# differential_evolution step 386: f(x)= 68.74409619558413
# differential_evolution step 387: f(x)= 68.74409619558413
# differential_evolution step 388: f(x)= 68.74084012245993
# differential_evolution step 389: f(x)= 68.74084012245993
# differential_evolution step 390: f(x)= 68.74034414324467
# differential_evolution step 391: f(x)= 68.74034414324467
# differential_evolution step 392: f(x)= 68.74034414324467
# differential_evolution step 393: f(x)= 68.74034414324467
# differential_evolution step 394: f(x)= 68.7390116655251
# differential_evolution step 395: f(x)= 68.7390116655251
# differential_evolution step 396: f(x)= 68.7390116655251
# differential_evolution step 397: f(x)= 68.7390116655251
# differential_evolution step 398: f(x)= 68.7390116655251
# differential_evolution step 399: f(x)= 68.7390116655251
# differential_evolution step 400: f(x)= 68.7390116655251
# differential_evolution step 401: f(x)= 68.7390116655251
# differential_evolution step 402: f(x)= 68.7390116655251
# differential_evolution step 403: f(x)= 68.7390116655251
# differential_evolution step 404: f(x)= 68.7390116655251
# differential_evolution step 405: f(x)= 68.73757661440253
# differential_evolution step 406: f(x)= 68.73757661440253
# differential_evolution step 407: f(x)= 68.73757661440253
# differential_evolution step 408: f(x)= 68.73757661440253
# differential_evolution step 409: f(x)= 68.73757661440253
# differential_evolution step 410: f(x)= 68.73757661440253
# differential_evolution step 411: f(x)= 68.73757661440253
# differential_evolution step 412: f(x)= 68.73757661440253
# differential_evolution step 413: f(x)= 68.73757661440253
# differential_evolution step 414: f(x)= 68.7362646708376
# differential_evolution step 415: f(x)= 68.7362646708376
# differential_evolution step 416: f(x)= 68.7362646708376
# differential_evolution step 417: f(x)= 68.7362646708376
# differential_evolution step 418: f(x)= 68.7362646708376
# differential_evolution step 419: f(x)= 68.7362646708376
# differential_evolution step 420: f(x)= 68.7362646708376
# differential_evolution step 421: f(x)= 68.7362646708376
# differential_evolution step 422: f(x)= 68.7362646708376
# differential_evolution step 423: f(x)= 68.7362646708376
# differential_evolution step 424: f(x)= 68.7362646708376
# differential_evolution step 425: f(x)= 68.7362646708376
# differential_evolution step 426: f(x)= 68.7362646708376
# differential_evolution step 427: f(x)= 68.7362646708376
# differential_evolution step 428: f(x)= 68.7362646708376
# differential_evolution step 429: f(x)= 68.73599607391077
# differential_evolution step 430: f(x)= 68.73599607391077
# differential_evolution step 431: f(x)= 68.73599607391077
# differential_evolution step 432: f(x)= 68.73599607391077
# differential_evolution step 433: f(x)= 68.73599607391077
# differential_evolution step 434: f(x)= 68.73599607391077
# differential_evolution step 435: f(x)= 68.73599607391077
# differential_evolution step 436: f(x)= 68.73599607391077
# differential_evolution step 437: f(x)= 68.73599026438465
# differential_evolution step 438: f(x)= 68.73599026438465
# differential_evolution step 439: f(x)= 68.73431403272394
# differential_evolution step 440: f(x)= 68.73431403272394
# differential_evolution step 441: f(x)= 68.73431403272394
# differential_evolution step 442: f(x)= 68.73431403272394
# differential_evolution step 443: f(x)= 68.73431403272394
# differential_evolution step 444: f(x)= 68.73431403272394
# differential_evolution step 445: f(x)= 68.73431403272394
# differential_evolution step 446: f(x)= 68.73431403272394
# differential_evolution step 447: f(x)= 68.73431403272394
# differential_evolution step 448: f(x)= 68.73431403272394
# differential_evolution step 449: f(x)= 68.73431403272394
# differential_evolution step 450: f(x)= 68.73431403272394
# differential_evolution step 451: f(x)= 68.73431403272394
# differential_evolution step 452: f(x)= 68.73431403272394
# differential_evolution step 453: f(x)= 68.73431403272394
# differential_evolution step 454: f(x)= 68.73431403272394
# differential_evolution step 455: f(x)= 68.73431403272394
# differential_evolution step 456: f(x)= 68.73367824280972
# differential_evolution step 457: f(x)= 68.73367824280972
# differential_evolution step 458: f(x)= 68.73273083546121
# differential_evolution step 459: f(x)= 68.73273083546121
# differential_evolution step 460: f(x)= 68.73273083546121
# differential_evolution step 461: f(x)= 68.73273083546121
# differential_evolution step 462: f(x)= 68.73273083546121
# differential_evolution step 463: f(x)= 68.73273083546121
# differential_evolution step 464: f(x)= 68.73273083546121
# differential_evolution step 465: f(x)= 68.73273083546121
# differential_evolution step 466: f(x)= 68.73273083546121
# differential_evolution step 467: f(x)= 68.73273083546121
# differential_evolution step 468: f(x)= 68.73273083546121
# differential_evolution step 469: f(x)= 68.73273083546121
# differential_evolution step 470: f(x)= 68.73273083546121
# differential_evolution step 471: f(x)= 68.73273083546121
# differential_evolution step 472: f(x)= 68.73273083546121
# differential_evolution step 473: f(x)= 68.73273083546121
# differential_evolution step 474: f(x)= 68.73269914515579
# differential_evolution step 475: f(x)= 68.73269914515579
# differential_evolution step 476: f(x)= 68.73269914515579
# differential_evolution step 477: f(x)= 68.73269914515579
# differential_evolution step 478: f(x)= 68.73269914515579
# differential_evolution step 479: f(x)= 68.73269914515579
# differential_evolution step 480: f(x)= 68.73269914515579
# differential_evolution step 481: f(x)= 68.73269914515579
# differential_evolution step 482: f(x)= 68.73269914515579
# differential_evolution step 483: f(x)= 68.73269914515579
# differential_evolution step 484: f(x)= 68.73269914515579
# differential_evolution step 485: f(x)= 68.73269914515579
# differential_evolution step 486: f(x)= 68.73269914515579
# differential_evolution step 487: f(x)= 68.73269914515579
# differential_evolution step 488: f(x)= 68.73269914515579
# differential_evolution step 489: f(x)= 68.73269914515579
# differential_evolution step 490: f(x)= 68.73269914515579
# differential_evolution step 491: f(x)= 68.73264533289345
# differential_evolution step 492: f(x)= 68.73264533289345
# differential_evolution step 493: f(x)= 68.73264533289345
# differential_evolution step 494: f(x)= 68.73264533289345
# differential_evolution step 495: f(x)= 68.73264533289345
# differential_evolution step 496: f(x)= 68.73244846678729
# differential_evolution step 497: f(x)= 68.73228334533333
# differential_evolution step 498: f(x)= 68.73228334533333
# differential_evolution step 499: f(x)= 68.73228334533333
# differential_evolution step 500: f(x)= 68.73228334533333
# differential_evolution step 501: f(x)= 68.73228334533333
# differential_evolution step 502: f(x)= 68.73228334533333
# differential_evolution step 503: f(x)= 68.73228334533333
# differential_evolution step 504: f(x)= 68.73228334533333
# differential_evolution step 505: f(x)= 68.73228334533333
# differential_evolution step 506: f(x)= 68.73228334533333
# differential_evolution step 507: f(x)= 68.73228334533333
# differential_evolution step 508: f(x)= 68.73228334533333
# differential_evolution step 509: f(x)= 68.73228334533333
# differential_evolution step 510: f(x)= 68.73228334533333
# differential_evolution step 511: f(x)= 68.73228334533333
# differential_evolution step 512: f(x)= 68.73228334533333
# differential_evolution step 513: f(x)= 68.73228334533333
# differential_evolution step 514: f(x)= 68.73228334533333
# differential_evolution step 515: f(x)= 68.73228334533333
# differential_evolution step 516: f(x)= 68.73228334533333
# differential_evolution step 517: f(x)= 68.73228334533333
# differential_evolution step 518: f(x)= 68.73228334533333
# differential_evolution step 519: f(x)= 68.73210283369637
# differential_evolution step 520: f(x)= 68.73210283369637
# differential_evolution step 521: f(x)= 68.73210283369637
# differential_evolution step 522: f(x)= 68.73210283369637
# differential_evolution step 523: f(x)= 68.73210283369637
# differential_evolution step 524: f(x)= 68.73210283369637
# differential_evolution step 525: f(x)= 68.73210283369637
# differential_evolution step 526: f(x)= 68.73210283369637
# differential_evolution step 527: f(x)= 68.73210283369637
# differential_evolution step 528: f(x)= 68.73210283369637
# differential_evolution step 529: f(x)= 68.73210283369637
# differential_evolution step 530: f(x)= 68.73210283369637
# differential_evolution step 531: f(x)= 68.73210283369637
# differential_evolution step 532: f(x)= 68.73210283369637
# differential_evolution step 533: f(x)= 68.73210283369637
# differential_evolution step 534: f(x)= 68.73210283369637
# differential_evolution step 535: f(x)= 68.73210283369637
# differential_evolution step 536: f(x)= 68.73210283369637
# differential_evolution step 537: f(x)= 68.73203915598205
# differential_evolution step 538: f(x)= 68.73203915598205
# differential_evolution step 539: f(x)= 68.73203915598205
# differential_evolution step 540: f(x)= 68.73203915598205
# differential_evolution step 541: f(x)= 68.73203915598205
# differential_evolution step 542: f(x)= 68.73203915598205
# differential_evolution step 543: f(x)= 68.73203915598205
# differential_evolution step 544: f(x)= 68.73203915598205
# differential_evolution step 545: f(x)= 68.73203915598205
# differential_evolution step 546: f(x)= 68.73203915598205
# differential_evolution step 547: f(x)= 68.73203915598205
# differential_evolution step 548: f(x)= 68.73203366232215
# differential_evolution step 549: f(x)= 68.73203366232215
# differential_evolution step 550: f(x)= 68.73203366232215
# differential_evolution step 551: f(x)= 68.73203366232215
# differential_evolution step 552: f(x)= 68.73203366232215
# differential_evolution step 553: f(x)= 68.73203366232215
# differential_evolution step 554: f(x)= 68.73203366232215
# differential_evolution step 555: f(x)= 68.73203366232215
# differential_evolution step 556: f(x)= 68.73203366232215
# differential_evolution step 557: f(x)= 68.73203366232215
# differential_evolution step 558: f(x)= 68.73201277591349
# differential_evolution step 559: f(x)= 68.73201277591349
# differential_evolution step 560: f(x)= 68.73201277591349
# differential_evolution step 561: f(x)= 68.73201277591349
# differential_evolution step 562: f(x)= 68.73201277591349
# differential_evolution step 563: f(x)= 68.73201277591349
# differential_evolution step 564: f(x)= 68.73201277591349
# differential_evolution step 565: f(x)= 68.73201277591349
# differential_evolution step 566: f(x)= 68.73201277591349
# differential_evolution step 567: f(x)= 68.73192947580601
# differential_evolution step 568: f(x)= 68.73192947580601
# differential_evolution step 569: f(x)= 68.73192947580601
# differential_evolution step 570: f(x)= 68.73192947580601
# differential_evolution step 571: f(x)= 68.73192947580601
# differential_evolution step 572: f(x)= 68.73192947580601
# differential_evolution step 573: f(x)= 68.73192947580601
# differential_evolution step 574: f(x)= 68.73192947580601
# differential_evolution step 575: f(x)= 68.73192947580601
# differential_evolution step 576: f(x)= 68.73192947580601
# differential_evolution step 577: f(x)= 68.73192947580601
# differential_evolution step 578: f(x)= 68.73192947580601
# differential_evolution step 579: f(x)= 68.7318933760425
# differential_evolution step 580: f(x)= 68.7318933760425
# differential_evolution step 581: f(x)= 68.7318933760425
# differential_evolution step 582: f(x)= 68.7318933760425
# differential_evolution step 583: f(x)= 68.7318933760425
# differential_evolution step 584: f(x)= 68.7318933760425
# differential_evolution step 585: f(x)= 68.7318933760425
# differential_evolution step 586: f(x)= 68.7318933760425
# differential_evolution step 587: f(x)= 68.73189187769441
# differential_evolution step 588: f(x)= 68.73189187769441
# differential_evolution step 589: f(x)= 68.73189187769441
# differential_evolution step 590: f(x)= 68.73189187769441
# differential_evolution step 591: f(x)= 68.73189187769441
# differential_evolution step 592: f(x)= 68.73186259837473
# differential_evolution step 593: f(x)= 68.73186259837473
# differential_evolution step 594: f(x)= 68.73186259837473
# differential_evolution step 595: f(x)= 68.73186259837473
# differential_evolution step 596: f(x)= 68.73186259837473
# differential_evolution step 597: f(x)= 68.73186259837473
# differential_evolution step 598: f(x)= 68.73186259837473
# differential_evolution step 599: f(x)= 68.73186259837473
# differential_evolution step 600: f(x)= 68.73186259837473
# differential_evolution step 601: f(x)= 68.73185996185431
# differential_evolution step 602: f(x)= 68.73185996185431
# differential_evolution step 603: f(x)= 68.73185996185431
# differential_evolution step 604: f(x)= 68.73185996185431
# differential_evolution step 605: f(x)= 68.73185996185431
# differential_evolution step 606: f(x)= 68.73185996185431
# differential_evolution step 607: f(x)= 68.73185996185431
# differential_evolution step 608: f(x)= 68.73185996185431
# differential_evolution step 609: f(x)= 68.73185996185431
# differential_evolution step 610: f(x)= 68.73185996185431
# differential_evolution step 611: f(x)= 68.73185996185431
# differential_evolution step 612: f(x)= 68.73185996185431
# differential_evolution step 613: f(x)= 68.73185996185431
# differential_evolution step 614: f(x)= 68.73185996185431
# differential_evolution step 615: f(x)= 68.73185996185431
# differential_evolution step 616: f(x)= 68.73185879031428
# differential_evolution step 617: f(x)= 68.73185879031428
# differential_evolution step 618: f(x)= 68.7318526680202
# differential_evolution step 619: f(x)= 68.73184526754768
# differential_evolution step 620: f(x)= 68.73183349194711
# differential_evolution step 621: f(x)= 68.73183349194711
# differential_evolution step 622: f(x)= 68.73183349194711
# differential_evolution step 623: f(x)= 68.73183349194711
# differential_evolution step 624: f(x)= 68.73183349194711
# differential_evolution step 625: f(x)= 68.73183349194711
# differential_evolution step 626: f(x)= 68.73183349194711
# differential_evolution step 627: f(x)= 68.73183349194711
# differential_evolution step 628: f(x)= 68.73183349194711
# differential_evolution step 629: f(x)= 68.73183349194711
# differential_evolution step 630: f(x)= 68.73180783111874
# differential_evolution step 631: f(x)= 68.73180783111874
# differential_evolution step 632: f(x)= 68.73180783111874
# differential_evolution step 633: f(x)= 68.73180783111874
# differential_evolution step 634: f(x)= 68.73180783111874
# differential_evolution step 635: f(x)= 68.73180268921114
# differential_evolution step 636: f(x)= 68.73180268921114
# differential_evolution step 637: f(x)= 68.73180268921114
# differential_evolution step 638: f(x)= 68.73180268921114
# differential_evolution step 639: f(x)= 68.73180268921114
# differential_evolution step 640: f(x)= 68.73180268921114
# differential_evolution step 641: f(x)= 68.73180268921114
# differential_evolution step 642: f(x)= 68.73180268921114
# differential_evolution step 643: f(x)= 68.73180268921114
# differential_evolution step 644: f(x)= 68.73179930249526
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=36.8757, r_e=2.6335, n=0.6964, x_0=39.3940
# Sérsic 2: I_e=3.3581, r_e=12.3461, n=1.2165, x_0=48.6062
# Sérsic 3: I_e=3.6622, r_e=2.8199, n=1.1344, x_0=57.2519
# Chi quadro minimo: 68.73178490239577
# True

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=36.8757, r_e=2.6335, n=0.6964, x_0=39.3940
# Sérsic 2: I_e=3.3581, r_e=12.3461, n=1.2165, x_0=48.6062
# Sérsic 3: I_e=3.6622, r_e=2.8199, n=1.1344, x_0=57.2519
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(result.x)
# Out:
# [36.8757331   2.63349491  0.69642161 39.39401486  3.35808221 12.34607179
#   1.21645164 48.6062006   3.66220945  2.81988225  1.13438314 57.25188069]

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA)#, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=17.4599, r_e=3.9023, n=1.3285, x_0=39.6501
# Sérsic 2: I_e=1.7317, r_e=11.9603, n=1.6745, x_0=48.7750
# Sérsic 3: I_e=4.6686, r_e=3.8660, n=0.8977, x_0=57.1217
# [1.08797654 0.12166113 0.0627123  0.0624387  0.34217762 0.77673718
#  0.16807906 0.13133063 0.45876485 0.26371968 0.08774165 0.1237336 ]
# 3.3443624537043317

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 20),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1, x_0_HA[0]+1),   # x_0: circa la posizione di Halpha

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1, x_0_HA[2]+1),
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[0])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 29181.032751439954
# differential_evolution step 2: f(x)= 14951.084861713081
# differential_evolution step 3: f(x)= 13981.524347448589
# differential_evolution step 4: f(x)= 5996.833464999323
# differential_evolution step 5: f(x)= 5996.833464999323
# differential_evolution step 6: f(x)= 1044.7363943093576
# differential_evolution step 7: f(x)= 564.2470265912084
# differential_evolution step 8: f(x)= 564.2470265912084
# differential_evolution step 9: f(x)= 564.2470265912084
# differential_evolution step 10: f(x)= 564.2470265912084
# differential_evolution step 11: f(x)= 564.2470265912084
# differential_evolution step 12: f(x)= 448.29713013294935
# differential_evolution step 13: f(x)= 448.29713013294935
# differential_evolution step 14: f(x)= 275.85465081009016
# differential_evolution step 15: f(x)= 275.85465081009016
# differential_evolution step 16: f(x)= 161.24264757968004
# differential_evolution step 17: f(x)= 161.24264757968004
# differential_evolution step 18: f(x)= 161.24264757968004
# differential_evolution step 19: f(x)= 161.24264757968004
# differential_evolution step 20: f(x)= 161.24264757968004
# differential_evolution step 21: f(x)= 161.24264757968004
# differential_evolution step 22: f(x)= 141.46121422110315
# differential_evolution step 23: f(x)= 141.46121422110315
# differential_evolution step 24: f(x)= 141.46121422110315
# differential_evolution step 25: f(x)= 141.46121422110315
# differential_evolution step 26: f(x)= 141.46121422110315
# differential_evolution step 27: f(x)= 76.22662200558257
# differential_evolution step 28: f(x)= 76.22662200558257
# differential_evolution step 29: f(x)= 76.22662200558257
# differential_evolution step 30: f(x)= 76.22662200558257
# differential_evolution step 31: f(x)= 76.22662200558257
# differential_evolution step 32: f(x)= 76.22662200558257
# differential_evolution step 33: f(x)= 76.22662200558257
# differential_evolution step 34: f(x)= 76.22662200558257
# differential_evolution step 35: f(x)= 76.22662200558257
# differential_evolution step 36: f(x)= 76.22662200558257
# differential_evolution step 37: f(x)= 76.22662200558257
# differential_evolution step 38: f(x)= 76.22662200558257
# differential_evolution step 39: f(x)= 76.22662200558257
# differential_evolution step 40: f(x)= 69.64191313938407
# differential_evolution step 41: f(x)= 69.64191313938407
# differential_evolution step 42: f(x)= 69.64191313938407
# differential_evolution step 43: f(x)= 69.64191313938407
# differential_evolution step 44: f(x)= 69.64191313938407
# differential_evolution step 45: f(x)= 69.64191313938407
# differential_evolution step 46: f(x)= 55.83549058666472
# differential_evolution step 47: f(x)= 40.822568059951514
# differential_evolution step 48: f(x)= 40.822568059951514
# differential_evolution step 49: f(x)= 40.822568059951514
# differential_evolution step 50: f(x)= 40.822568059951514
# differential_evolution step 51: f(x)= 40.822568059951514
# differential_evolution step 52: f(x)= 40.822568059951514
# differential_evolution step 53: f(x)= 40.822568059951514
# differential_evolution step 54: f(x)= 40.822568059951514
# differential_evolution step 55: f(x)= 40.822568059951514
# differential_evolution step 56: f(x)= 37.01476810108316
# differential_evolution step 57: f(x)= 37.01476810108316
# differential_evolution step 58: f(x)= 37.01476810108316
# differential_evolution step 59: f(x)= 37.01476810108316
# differential_evolution step 60: f(x)= 37.01476810108316
# differential_evolution step 61: f(x)= 37.01476810108316
# differential_evolution step 62: f(x)= 37.01476810108316
# differential_evolution step 63: f(x)= 37.01476810108316
# differential_evolution step 64: f(x)= 34.70189453395513
# differential_evolution step 65: f(x)= 34.70189453395513
# differential_evolution step 66: f(x)= 34.70189453395513
# differential_evolution step 67: f(x)= 29.60957117495656
# differential_evolution step 68: f(x)= 29.60957117495656
# differential_evolution step 69: f(x)= 29.60957117495656
# differential_evolution step 70: f(x)= 29.60957117495656
# differential_evolution step 71: f(x)= 29.60957117495656
# differential_evolution step 72: f(x)= 29.60957117495656
# differential_evolution step 73: f(x)= 29.60957117495656
# differential_evolution step 74: f(x)= 29.60957117495656
# differential_evolution step 75: f(x)= 29.60957117495656
# differential_evolution step 76: f(x)= 27.267644482857705
# differential_evolution step 77: f(x)= 27.026266918283216
# differential_evolution step 78: f(x)= 27.026266918283216
# differential_evolution step 79: f(x)= 27.026266918283216
# differential_evolution step 80: f(x)= 27.026266918283216
# differential_evolution step 81: f(x)= 27.026266918283216
# differential_evolution step 82: f(x)= 27.026266918283216
# differential_evolution step 83: f(x)= 27.026266918283216
# differential_evolution step 84: f(x)= 27.026266918283216
# differential_evolution step 85: f(x)= 27.026266918283216
# differential_evolution step 86: f(x)= 27.026266918283216
# differential_evolution step 87: f(x)= 21.871584623491273
# differential_evolution step 88: f(x)= 21.871584623491273
# differential_evolution step 89: f(x)= 21.871584623491273
# differential_evolution step 90: f(x)= 21.871584623491273
# differential_evolution step 91: f(x)= 21.871584623491273
# differential_evolution step 92: f(x)= 21.871584623491273
# differential_evolution step 93: f(x)= 21.871584623491273
# differential_evolution step 94: f(x)= 21.871584623491273
# differential_evolution step 95: f(x)= 21.871584623491273
# differential_evolution step 96: f(x)= 21.871584623491273
# differential_evolution step 97: f(x)= 21.871584623491273
# differential_evolution step 98: f(x)= 21.871584623491273
# differential_evolution step 99: f(x)= 21.871584623491273
# differential_evolution step 100: f(x)= 21.871584623491273
# differential_evolution step 101: f(x)= 21.871584623491273
# differential_evolution step 102: f(x)= 21.871584623491273
# differential_evolution step 103: f(x)= 21.871584623491273
# differential_evolution step 104: f(x)= 21.871584623491273
# differential_evolution step 105: f(x)= 21.871584623491273
# differential_evolution step 106: f(x)= 19.200050229597142
# differential_evolution step 107: f(x)= 19.200050229597142
# differential_evolution step 108: f(x)= 19.200050229597142
# differential_evolution step 109: f(x)= 18.795799589436626
# differential_evolution step 110: f(x)= 18.795799589436626
# differential_evolution step 111: f(x)= 18.795799589436626
# differential_evolution step 112: f(x)= 18.795799589436626
# differential_evolution step 113: f(x)= 18.795799589436626
# differential_evolution step 114: f(x)= 17.742420983699184
# differential_evolution step 115: f(x)= 17.742420983699184
# differential_evolution step 116: f(x)= 16.78750457959226
# differential_evolution step 117: f(x)= 16.78750457959226
# differential_evolution step 118: f(x)= 16.78750457959226
# differential_evolution step 119: f(x)= 16.78750457959226
# differential_evolution step 120: f(x)= 16.78750457959226
# differential_evolution step 121: f(x)= 16.532589503611877
# differential_evolution step 122: f(x)= 16.532589503611877
# differential_evolution step 123: f(x)= 16.532589503611877
# differential_evolution step 124: f(x)= 16.532589503611877
# differential_evolution step 125: f(x)= 16.532589503611877
# differential_evolution step 126: f(x)= 16.532589503611877
# differential_evolution step 127: f(x)= 15.988499824773779
# differential_evolution step 128: f(x)= 15.988499824773779
# differential_evolution step 129: f(x)= 15.988499824773779
# differential_evolution step 130: f(x)= 14.087627680972956
# differential_evolution step 131: f(x)= 14.087627680972956
# differential_evolution step 132: f(x)= 14.087627680972956
# differential_evolution step 133: f(x)= 14.087627680972956
# differential_evolution step 134: f(x)= 14.087627680972956
# differential_evolution step 135: f(x)= 14.087627680972956
# differential_evolution step 136: f(x)= 14.087627680972956
# differential_evolution step 137: f(x)= 14.087627680972956
# differential_evolution step 138: f(x)= 14.087627680972956
# differential_evolution step 139: f(x)= 14.087627680972956
# differential_evolution step 140: f(x)= 14.087627680972956
# differential_evolution step 141: f(x)= 14.087627680972956
# differential_evolution step 142: f(x)= 14.087627680972956
# differential_evolution step 143: f(x)= 14.087627680972956
# differential_evolution step 144: f(x)= 14.087627680972956
# differential_evolution step 145: f(x)= 14.087627680972956
# differential_evolution step 146: f(x)= 13.911373900896931
# differential_evolution step 147: f(x)= 13.911373900896931
# differential_evolution step 148: f(x)= 13.911373900896931
# differential_evolution step 149: f(x)= 13.911373900896931
# differential_evolution step 150: f(x)= 13.911373900896931
# differential_evolution step 151: f(x)= 13.911373900896931
# differential_evolution step 152: f(x)= 13.911373900896931
# differential_evolution step 153: f(x)= 13.911373900896931
# differential_evolution step 154: f(x)= 13.911373900896931
# differential_evolution step 155: f(x)= 13.911373900896931
# differential_evolution step 156: f(x)= 13.911373900896931
# differential_evolution step 157: f(x)= 13.911373900896931
# differential_evolution step 158: f(x)= 13.911373900896931
# differential_evolution step 159: f(x)= 13.911373900896931
# differential_evolution step 160: f(x)= 13.739005383673325
# differential_evolution step 161: f(x)= 13.739005383673325
# differential_evolution step 162: f(x)= 13.739005383673325
# differential_evolution step 163: f(x)= 13.662621392948324
# differential_evolution step 164: f(x)= 13.662621392948324
# differential_evolution step 165: f(x)= 13.270931040477729
# differential_evolution step 166: f(x)= 13.270931040477729
# differential_evolution step 167: f(x)= 13.270931040477729
# differential_evolution step 168: f(x)= 13.270931040477729
# differential_evolution step 169: f(x)= 13.270931040477729
# differential_evolution step 170: f(x)= 13.270931040477729
# differential_evolution step 171: f(x)= 13.270931040477729
# differential_evolution step 172: f(x)= 13.270931040477729
# differential_evolution step 173: f(x)= 13.270931040477729
# differential_evolution step 174: f(x)= 12.894285080154866
# differential_evolution step 175: f(x)= 12.894285080154866
# differential_evolution step 176: f(x)= 12.894285080154866
# differential_evolution step 177: f(x)= 12.894285080154866
# differential_evolution step 178: f(x)= 12.894285080154866
# differential_evolution step 179: f(x)= 12.894285080154866
# differential_evolution step 180: f(x)= 12.894285080154866
# differential_evolution step 181: f(x)= 12.894285080154866
# differential_evolution step 182: f(x)= 12.894285080154866
# differential_evolution step 183: f(x)= 12.894285080154866
# differential_evolution step 184: f(x)= 12.894285080154866
# differential_evolution step 185: f(x)= 12.894285080154866
# differential_evolution step 186: f(x)= 12.894285080154866
# differential_evolution step 187: f(x)= 12.894285080154866
# differential_evolution step 188: f(x)= 12.894285080154866
# differential_evolution step 189: f(x)= 12.894285080154866
# differential_evolution step 190: f(x)= 12.894285080154866
# differential_evolution step 191: f(x)= 12.894285080154866
# differential_evolution step 192: f(x)= 12.894285080154866
# differential_evolution step 193: f(x)= 12.894285080154866
# differential_evolution step 194: f(x)= 12.894285080154866
# differential_evolution step 195: f(x)= 12.894285080154866
# differential_evolution step 196: f(x)= 12.894285080154866
# differential_evolution step 197: f(x)= 12.894285080154866
# differential_evolution step 198: f(x)= 12.894285080154866
# differential_evolution step 199: f(x)= 12.894285080154866
# differential_evolution step 200: f(x)= 12.894285080154866
# differential_evolution step 201: f(x)= 12.894285080154866
# differential_evolution step 202: f(x)= 12.894285080154866
# differential_evolution step 203: f(x)= 12.714603672599575
# differential_evolution step 204: f(x)= 12.714603672599575
# differential_evolution step 205: f(x)= 12.714603672599575
# differential_evolution step 206: f(x)= 12.714603672599575
# differential_evolution step 207: f(x)= 12.714603672599575
# differential_evolution step 208: f(x)= 12.714603672599575
# differential_evolution step 209: f(x)= 12.453681812104247
# differential_evolution step 210: f(x)= 12.453681812104247
# differential_evolution step 211: f(x)= 12.453681812104247
# differential_evolution step 212: f(x)= 12.453681812104247
# differential_evolution step 213: f(x)= 12.453681812104247
# differential_evolution step 214: f(x)= 12.355334252475688
# differential_evolution step 215: f(x)= 12.355334252475688
# differential_evolution step 216: f(x)= 12.355334252475688
# differential_evolution step 217: f(x)= 12.355334252475688
# differential_evolution step 218: f(x)= 12.355334252475688
# differential_evolution step 219: f(x)= 12.355334252475688
# differential_evolution step 220: f(x)= 12.355334252475688
# differential_evolution step 221: f(x)= 12.355334252475688
# differential_evolution step 222: f(x)= 12.355334252475688
# differential_evolution step 223: f(x)= 12.355334252475688
# differential_evolution step 224: f(x)= 12.355334252475688
# differential_evolution step 225: f(x)= 12.355334252475688
# differential_evolution step 226: f(x)= 12.355334252475688
# differential_evolution step 227: f(x)= 12.355334252475688
# differential_evolution step 228: f(x)= 12.355334252475688
# differential_evolution step 229: f(x)= 12.355334252475688
# differential_evolution step 230: f(x)= 12.355334252475688
# differential_evolution step 231: f(x)= 12.355334252475688
# differential_evolution step 232: f(x)= 12.355334252475688
# differential_evolution step 233: f(x)= 12.355334252475688
# differential_evolution step 234: f(x)= 12.355334252475688
# differential_evolution step 235: f(x)= 12.355334252475688
# differential_evolution step 236: f(x)= 12.355334252475688
# differential_evolution step 237: f(x)= 12.355334252475688
# differential_evolution step 238: f(x)= 12.355334252475688
# differential_evolution step 239: f(x)= 12.140312450501195
# differential_evolution step 240: f(x)= 12.140312450501195
# differential_evolution step 241: f(x)= 12.140312450501195
# differential_evolution step 242: f(x)= 12.140312450501195
# differential_evolution step 243: f(x)= 12.140312450501195
# differential_evolution step 244: f(x)= 12.140312450501195
# differential_evolution step 245: f(x)= 12.140312450501195
# differential_evolution step 246: f(x)= 12.140312450501195
# differential_evolution step 247: f(x)= 12.140312450501195
# differential_evolution step 248: f(x)= 12.140312450501195
# differential_evolution step 249: f(x)= 12.140312450501195
# differential_evolution step 250: f(x)= 12.140312450501195
# differential_evolution step 251: f(x)= 12.140312450501195
# differential_evolution step 252: f(x)= 12.140312450501195
# differential_evolution step 253: f(x)= 12.140312450501195
# differential_evolution step 254: f(x)= 12.140312450501195
# differential_evolution step 255: f(x)= 12.112422338627118
# differential_evolution step 256: f(x)= 12.112422338627118
# differential_evolution step 257: f(x)= 12.112422338627118
# differential_evolution step 258: f(x)= 12.112422338627118
# differential_evolution step 259: f(x)= 12.112422338627118
# differential_evolution step 260: f(x)= 12.112422338627118
# differential_evolution step 261: f(x)= 12.112422338627118
# differential_evolution step 262: f(x)= 12.011981153703621
# differential_evolution step 263: f(x)= 12.011981153703621
# differential_evolution step 264: f(x)= 11.952631365369204
# differential_evolution step 265: f(x)= 11.952631365369204
# differential_evolution step 266: f(x)= 11.952631365369204
# differential_evolution step 267: f(x)= 11.952631365369204
# differential_evolution step 268: f(x)= 11.952631365369204
# differential_evolution step 269: f(x)= 11.952631365369204
# differential_evolution step 270: f(x)= 11.952631365369204
# differential_evolution step 271: f(x)= 11.952631365369204
# differential_evolution step 272: f(x)= 11.952631365369204
# differential_evolution step 273: f(x)= 11.952631365369204
# differential_evolution step 274: f(x)= 11.952631365369204
# differential_evolution step 275: f(x)= 11.952631365369204
# differential_evolution step 276: f(x)= 11.952631365369204
# differential_evolution step 277: f(x)= 11.91163152501795
# differential_evolution step 278: f(x)= 11.91163152501795
# differential_evolution step 279: f(x)= 11.91163152501795
# differential_evolution step 280: f(x)= 11.91163152501795
# differential_evolution step 281: f(x)= 11.91163152501795
# differential_evolution step 282: f(x)= 11.91163152501795
# differential_evolution step 283: f(x)= 11.91163152501795
# differential_evolution step 284: f(x)= 11.91163152501795
# differential_evolution step 285: f(x)= 11.91163152501795
# differential_evolution step 286: f(x)= 11.824990876754672
# differential_evolution step 287: f(x)= 11.824990876754672
# differential_evolution step 288: f(x)= 11.824990876754672
# differential_evolution step 289: f(x)= 11.824990876754672
# differential_evolution step 290: f(x)= 11.824990876754672
# differential_evolution step 291: f(x)= 11.824990876754672
# differential_evolution step 292: f(x)= 11.824990876754672
# differential_evolution step 293: f(x)= 11.824990876754672
# differential_evolution step 294: f(x)= 11.824990876754672
# differential_evolution step 295: f(x)= 11.824990876754672
# differential_evolution step 296: f(x)= 11.824990876754672
# differential_evolution step 297: f(x)= 11.787722957364256
# differential_evolution step 298: f(x)= 11.787722957364256
# differential_evolution step 299: f(x)= 11.787722957364256
# differential_evolution step 300: f(x)= 11.787722957364256
# differential_evolution step 301: f(x)= 11.787722957364256
# differential_evolution step 302: f(x)= 11.787722957364256
# differential_evolution step 303: f(x)= 11.787722957364256
# differential_evolution step 304: f(x)= 11.787722957364256
# differential_evolution step 305: f(x)= 11.787722957364256
# differential_evolution step 306: f(x)= 11.787722957364256
# differential_evolution step 307: f(x)= 11.787722957364256
# differential_evolution step 308: f(x)= 11.787722957364256
# differential_evolution step 309: f(x)= 11.787722957364256
# differential_evolution step 310: f(x)= 11.787722957364256
# differential_evolution step 311: f(x)= 11.787722957364256
# differential_evolution step 312: f(x)= 11.787722957364256
# differential_evolution step 313: f(x)= 11.787722957364256
# differential_evolution step 314: f(x)= 11.787722957364256
# differential_evolution step 315: f(x)= 11.787722957364256
# differential_evolution step 316: f(x)= 11.787722957364256
# differential_evolution step 317: f(x)= 11.787722957364256
# differential_evolution step 318: f(x)= 11.787722957364256
# differential_evolution step 319: f(x)= 11.787722957364256
# differential_evolution step 320: f(x)= 11.787722957364256
# differential_evolution step 321: f(x)= 11.787722957364256
# differential_evolution step 322: f(x)= 11.787722957364256
# differential_evolution step 323: f(x)= 11.787722957364256
# differential_evolution step 324: f(x)= 11.787722957364256
# differential_evolution step 325: f(x)= 11.787722957364256
# differential_evolution step 326: f(x)= 11.787722957364256
# differential_evolution step 327: f(x)= 11.787722957364256
# differential_evolution step 328: f(x)= 11.787722957364256
# differential_evolution step 329: f(x)= 11.787722957364256
# differential_evolution step 330: f(x)= 11.787722957364256
# differential_evolution step 331: f(x)= 11.787722957364256
# differential_evolution step 332: f(x)= 11.787722957364256
# differential_evolution step 333: f(x)= 11.787722957364256
# differential_evolution step 334: f(x)= 11.787722957364256
# differential_evolution step 335: f(x)= 11.787722957364256
# differential_evolution step 336: f(x)= 11.787722957364256
# differential_evolution step 337: f(x)= 11.787722957364256
# differential_evolution step 338: f(x)= 11.787722957364256
# differential_evolution step 339: f(x)= 11.787722957364256
# differential_evolution step 340: f(x)= 11.787722957364256
# differential_evolution step 341: f(x)= 11.785222707303289
# differential_evolution step 342: f(x)= 11.785222707303289
# differential_evolution step 343: f(x)= 11.785222707303289
# differential_evolution step 344: f(x)= 11.785222707303289
# differential_evolution step 345: f(x)= 11.785222707303289
# differential_evolution step 346: f(x)= 11.785222707303289
# differential_evolution step 347: f(x)= 11.785222707303289
# differential_evolution step 348: f(x)= 11.785222707303289
# differential_evolution step 349: f(x)= 11.785222707303289
# differential_evolution step 350: f(x)= 11.785222707303289
# differential_evolution step 351: f(x)= 11.785222707303289
# differential_evolution step 352: f(x)= 11.74404685305021
# differential_evolution step 353: f(x)= 11.74404685305021
# differential_evolution step 354: f(x)= 11.74404685305021
# differential_evolution step 355: f(x)= 11.74404685305021
# differential_evolution step 356: f(x)= 11.74404685305021
# differential_evolution step 357: f(x)= 11.74404685305021
# differential_evolution step 358: f(x)= 11.74404685305021
# differential_evolution step 359: f(x)= 11.74404685305021
# differential_evolution step 360: f(x)= 11.74404685305021
# differential_evolution step 361: f(x)= 11.74404685305021
# differential_evolution step 362: f(x)= 11.74404685305021
# differential_evolution step 363: f(x)= 11.74404685305021
# differential_evolution step 364: f(x)= 11.74404685305021
# differential_evolution step 365: f(x)= 11.74404685305021
# differential_evolution step 366: f(x)= 11.74404685305021
# differential_evolution step 367: f(x)= 11.74404685305021
# differential_evolution step 368: f(x)= 11.74404685305021
# differential_evolution step 369: f(x)= 11.74404685305021
# differential_evolution step 370: f(x)= 11.74404685305021
# differential_evolution step 371: f(x)= 11.74404685305021
# differential_evolution step 372: f(x)= 11.74404685305021
# differential_evolution step 373: f(x)= 11.74404685305021
# differential_evolution step 374: f(x)= 11.74404685305021
# differential_evolution step 375: f(x)= 11.74404685305021
# differential_evolution step 376: f(x)= 11.74404685305021
# differential_evolution step 377: f(x)= 11.74404685305021
# differential_evolution step 378: f(x)= 11.74404685305021
# differential_evolution step 379: f(x)= 11.74404685305021
# differential_evolution step 380: f(x)= 11.74404685305021
# differential_evolution step 381: f(x)= 11.715002613596075
# differential_evolution step 382: f(x)= 11.715002613596075
# differential_evolution step 383: f(x)= 11.715002613596075
# differential_evolution step 384: f(x)= 11.715002613596075
# differential_evolution step 385: f(x)= 11.710316881189753
# differential_evolution step 386: f(x)= 11.710316881189753
# differential_evolution step 387: f(x)= 11.710316881189753
# differential_evolution step 388: f(x)= 11.710316881189753
# differential_evolution step 389: f(x)= 11.710316881189753
# differential_evolution step 390: f(x)= 11.691543152013875
# differential_evolution step 391: f(x)= 11.691543152013875
# differential_evolution step 392: f(x)= 11.691543152013875
# differential_evolution step 393: f(x)= 11.691543152013875
# differential_evolution step 394: f(x)= 11.691543152013875
# differential_evolution step 395: f(x)= 11.691543152013875
# differential_evolution step 396: f(x)= 11.691543152013875
# differential_evolution step 397: f(x)= 11.691543152013875
# differential_evolution step 398: f(x)= 11.691543152013875
# differential_evolution step 399: f(x)= 11.691543152013875
# differential_evolution step 400: f(x)= 11.691543152013875
# differential_evolution step 401: f(x)= 11.691543152013875
# differential_evolution step 402: f(x)= 11.691543152013875
# differential_evolution step 403: f(x)= 11.691543152013875
# differential_evolution step 404: f(x)= 11.691543152013875
# differential_evolution step 405: f(x)= 11.691543152013875
# differential_evolution step 406: f(x)= 11.691543152013875
# differential_evolution step 407: f(x)= 11.691543152013875
# differential_evolution step 408: f(x)= 11.691543152013875
# differential_evolution step 409: f(x)= 11.691543152013875
# differential_evolution step 410: f(x)= 11.691543152013875
# differential_evolution step 411: f(x)= 11.691543152013875
# differential_evolution step 412: f(x)= 11.691543152013875
# differential_evolution step 413: f(x)= 11.691543152013875
# differential_evolution step 414: f(x)= 11.691543152013875
# differential_evolution step 415: f(x)= 11.691543152013875
# differential_evolution step 416: f(x)= 11.691543152013875
# differential_evolution step 417: f(x)= 11.691543152013875
# differential_evolution step 418: f(x)= 11.691543152013875
# differential_evolution step 419: f(x)= 11.691543152013875
# differential_evolution step 420: f(x)= 11.691543152013875
# differential_evolution step 421: f(x)= 11.691543152013875
# differential_evolution step 422: f(x)= 11.691543152013875
# differential_evolution step 423: f(x)= 11.691543152013875
# differential_evolution step 424: f(x)= 11.67914125018549
# differential_evolution step 425: f(x)= 11.67914125018549
# differential_evolution step 426: f(x)= 11.67914125018549
# differential_evolution step 427: f(x)= 11.67914125018549
# differential_evolution step 428: f(x)= 11.67914125018549
# differential_evolution step 429: f(x)= 11.67914125018549
# differential_evolution step 430: f(x)= 11.67914125018549
# differential_evolution step 431: f(x)= 11.664577781947159
# differential_evolution step 432: f(x)= 11.664577781947159
# differential_evolution step 433: f(x)= 11.664577781947159
# differential_evolution step 434: f(x)= 11.664577781947159
# differential_evolution step 435: f(x)= 11.664577781947159
# differential_evolution step 436: f(x)= 11.664577781947159
# differential_evolution step 437: f(x)= 11.664577781947159
# differential_evolution step 438: f(x)= 11.664577781947159
# differential_evolution step 439: f(x)= 11.664577781947159
# differential_evolution step 440: f(x)= 11.664577781947159
# differential_evolution step 441: f(x)= 11.664577781947159
# differential_evolution step 442: f(x)= 11.664577781947159
# differential_evolution step 443: f(x)= 11.664577781947159
# differential_evolution step 444: f(x)= 11.664577781947159
# differential_evolution step 445: f(x)= 11.664577781947159
# differential_evolution step 446: f(x)= 11.664577781947159
# differential_evolution step 447: f(x)= 11.664577781947159
# differential_evolution step 448: f(x)= 11.664577781947159
# differential_evolution step 449: f(x)= 11.664577781947159
# differential_evolution step 450: f(x)= 11.664577781947159
# differential_evolution step 451: f(x)= 11.664577781947159
# differential_evolution step 452: f(x)= 11.664577781947159
# differential_evolution step 453: f(x)= 11.664577781947159
# differential_evolution step 454: f(x)= 11.65375000547594
# differential_evolution step 455: f(x)= 11.65375000547594
# differential_evolution step 456: f(x)= 11.65375000547594
# differential_evolution step 457: f(x)= 11.65375000547594
# differential_evolution step 458: f(x)= 11.65375000547594
# differential_evolution step 459: f(x)= 11.65375000547594
# differential_evolution step 460: f(x)= 11.65375000547594
# differential_evolution step 461: f(x)= 11.65375000547594
# differential_evolution step 462: f(x)= 11.65375000547594
# differential_evolution step 463: f(x)= 11.65375000547594
# differential_evolution step 464: f(x)= 11.65375000547594
# differential_evolution step 465: f(x)= 11.65375000547594
# differential_evolution step 466: f(x)= 11.65375000547594
# differential_evolution step 467: f(x)= 11.65375000547594
# differential_evolution step 468: f(x)= 11.65375000547594
# differential_evolution step 469: f(x)= 11.65375000547594
# differential_evolution step 470: f(x)= 11.65375000547594
# differential_evolution step 471: f(x)= 11.65375000547594
# differential_evolution step 472: f(x)= 11.65375000547594
# differential_evolution step 473: f(x)= 11.65375000547594
# differential_evolution step 474: f(x)= 11.65375000547594
# differential_evolution step 475: f(x)= 11.65375000547594
# differential_evolution step 476: f(x)= 11.652720352856772
# differential_evolution step 477: f(x)= 11.652720352856772
# differential_evolution step 478: f(x)= 11.652720352856772
# differential_evolution step 479: f(x)= 11.652720352856772
# differential_evolution step 480: f(x)= 11.652720352856772
# differential_evolution step 481: f(x)= 11.652720352856772
# differential_evolution step 482: f(x)= 11.652720352856772
# differential_evolution step 483: f(x)= 11.652720352856772
# differential_evolution step 484: f(x)= 11.652720352856772
# differential_evolution step 485: f(x)= 11.652720352856772
# differential_evolution step 486: f(x)= 11.652720352856772
# differential_evolution step 487: f(x)= 11.652720352856772
# differential_evolution step 488: f(x)= 11.652720352856772
# differential_evolution step 489: f(x)= 11.652720352856772
# differential_evolution step 490: f(x)= 11.652720352856772
# differential_evolution step 491: f(x)= 11.652720352856772
# differential_evolution step 492: f(x)= 11.652720352856772
# differential_evolution step 493: f(x)= 11.652720352856772
# differential_evolution step 494: f(x)= 11.652720352856772
# differential_evolution step 495: f(x)= 11.652720352856772
# differential_evolution step 496: f(x)= 11.652720352856772
# differential_evolution step 497: f(x)= 11.652720352856772
# differential_evolution step 498: f(x)= 11.652720352856772
# differential_evolution step 499: f(x)= 11.652720352856772
# differential_evolution step 500: f(x)= 11.652720352856772
# differential_evolution step 501: f(x)= 11.652720352856772
# differential_evolution step 502: f(x)= 11.652720352856772
# differential_evolution step 503: f(x)= 11.652720352856772
# differential_evolution step 504: f(x)= 11.652720352856772
# differential_evolution step 505: f(x)= 11.649870990345262
# differential_evolution step 506: f(x)= 11.649870990345262
# differential_evolution step 507: f(x)= 11.649870990345262
# differential_evolution step 508: f(x)= 11.649870990345262
# differential_evolution step 509: f(x)= 11.644768050088137
# differential_evolution step 510: f(x)= 11.644768050088137
# differential_evolution step 511: f(x)= 11.644768050088137
# differential_evolution step 512: f(x)= 11.644768050088137
# differential_evolution step 513: f(x)= 11.644768050088137
# differential_evolution step 514: f(x)= 11.644768050088137
# differential_evolution step 515: f(x)= 11.644768050088137
# differential_evolution step 516: f(x)= 11.644768050088137
# differential_evolution step 517: f(x)= 11.644768050088137
# differential_evolution step 518: f(x)= 11.644744552352076
# differential_evolution step 519: f(x)= 11.644744552352076
# differential_evolution step 520: f(x)= 11.644744552352076
# differential_evolution step 521: f(x)= 11.644744552352076
# differential_evolution step 522: f(x)= 11.644744552352076
# differential_evolution step 523: f(x)= 11.644744552352076
# differential_evolution step 524: f(x)= 11.644744552352076
# differential_evolution step 525: f(x)= 11.644744552352076
# differential_evolution step 526: f(x)= 11.642603414555424
# differential_evolution step 527: f(x)= 11.642603414555424
# differential_evolution step 528: f(x)= 11.642603414555424
# differential_evolution step 529: f(x)= 11.642603414555424
# differential_evolution step 530: f(x)= 11.6422711545517
# differential_evolution step 531: f(x)= 11.6422711545517
# differential_evolution step 532: f(x)= 11.6422711545517
# differential_evolution step 533: f(x)= 11.6422711545517
# differential_evolution step 534: f(x)= 11.6422711545517
# differential_evolution step 535: f(x)= 11.640677308885675
# differential_evolution step 536: f(x)= 11.640677308885675
# differential_evolution step 537: f(x)= 11.640677308885675
# differential_evolution step 538: f(x)= 11.640677308885675
# differential_evolution step 539: f(x)= 11.640677308885675
# differential_evolution step 540: f(x)= 11.640677308885675
# differential_evolution step 541: f(x)= 11.640677308885675
# differential_evolution step 542: f(x)= 11.640677308885675
# differential_evolution step 543: f(x)= 11.640677308885675
# differential_evolution step 544: f(x)= 11.640677308885675
# differential_evolution step 545: f(x)= 11.640677308885675
# differential_evolution step 546: f(x)= 11.640677308885675
# differential_evolution step 547: f(x)= 11.640677308885675
# differential_evolution step 548: f(x)= 11.640677308885675
# differential_evolution step 549: f(x)= 11.640677308885675
# differential_evolution step 550: f(x)= 11.639273869660716
# differential_evolution step 551: f(x)= 11.639273869660716
# differential_evolution step 552: f(x)= 11.639273869660716
# differential_evolution step 553: f(x)= 11.639273869660716
# differential_evolution step 554: f(x)= 11.639273869660716
# differential_evolution step 555: f(x)= 11.639273869660716
# differential_evolution step 556: f(x)= 11.639273869660716
# differential_evolution step 557: f(x)= 11.639273869660716
# differential_evolution step 558: f(x)= 11.639273869660716
# differential_evolution step 559: f(x)= 11.639273869660716
# differential_evolution step 560: f(x)= 11.639273869660716
# differential_evolution step 561: f(x)= 11.639273869660716
# differential_evolution step 562: f(x)= 11.639273869660716
# differential_evolution step 563: f(x)= 11.639273869660716
# differential_evolution step 564: f(x)= 11.639273869660716
# differential_evolution step 565: f(x)= 11.639273869660716
# differential_evolution step 566: f(x)= 11.639273869660716
# differential_evolution step 567: f(x)= 11.639273869660716
# differential_evolution step 568: f(x)= 11.639273869660716
# differential_evolution step 569: f(x)= 11.639273869660716
# differential_evolution step 570: f(x)= 11.639273869660716
# differential_evolution step 571: f(x)= 11.639273869660716
# differential_evolution step 572: f(x)= 11.638957644489928
# differential_evolution step 573: f(x)= 11.638957644489928
# differential_evolution step 574: f(x)= 11.638957644489928
# differential_evolution step 575: f(x)= 11.638957644489928
# differential_evolution step 576: f(x)= 11.638957644489928
# differential_evolution step 577: f(x)= 11.638472979306082
# differential_evolution step 578: f(x)= 11.638472979306082
# differential_evolution step 579: f(x)= 11.638472979306082
# differential_evolution step 580: f(x)= 11.638472979306082
# differential_evolution step 581: f(x)= 11.638472979306082
# differential_evolution step 582: f(x)= 11.638472979306082
# differential_evolution step 583: f(x)= 11.638472979306082
# differential_evolution step 584: f(x)= 11.638472979306082
# differential_evolution step 585: f(x)= 11.638472979306082
# differential_evolution step 586: f(x)= 11.638472979306082
# differential_evolution step 587: f(x)= 11.638472979306082
# differential_evolution step 588: f(x)= 11.637773982564182
# differential_evolution step 589: f(x)= 11.637773982564182
# differential_evolution step 590: f(x)= 11.637773982564182
# differential_evolution step 591: f(x)= 11.637773982564182
# differential_evolution step 592: f(x)= 11.637773982564182
# differential_evolution step 593: f(x)= 11.637773982564182
# differential_evolution step 594: f(x)= 11.637773982564182
# differential_evolution step 595: f(x)= 11.637773982564182
# differential_evolution step 596: f(x)= 11.637773982564182
# differential_evolution step 597: f(x)= 11.637773982564182
# differential_evolution step 598: f(x)= 11.637731669293318
# differential_evolution step 599: f(x)= 11.637731669293318
# differential_evolution step 600: f(x)= 11.637731669293318
# differential_evolution step 601: f(x)= 11.637731669293318
# differential_evolution step 602: f(x)= 11.637731669293318
# differential_evolution step 603: f(x)= 11.637731669293318
# differential_evolution step 604: f(x)= 11.637731669293318
# differential_evolution step 605: f(x)= 11.637731669293318
# differential_evolution step 606: f(x)= 11.637731669293318
# differential_evolution step 607: f(x)= 11.637731669293318
# differential_evolution step 608: f(x)= 11.637731669293318
# differential_evolution step 609: f(x)= 11.637731669293318
# differential_evolution step 610: f(x)= 11.637731669293318
# differential_evolution step 611: f(x)= 11.637731669293318
# differential_evolution step 612: f(x)= 11.637731669293318
# differential_evolution step 613: f(x)= 11.637731669293318
# differential_evolution step 614: f(x)= 11.637731669293318
# differential_evolution step 615: f(x)= 11.637731669293318
# differential_evolution step 616: f(x)= 11.637731669293318
# differential_evolution step 617: f(x)= 11.637731669293318
# differential_evolution step 618: f(x)= 11.637731669293318
# differential_evolution step 619: f(x)= 11.637731669293318
# differential_evolution step 620: f(x)= 11.636571905722619
# differential_evolution step 621: f(x)= 11.636571905722619
# differential_evolution step 622: f(x)= 11.636571905722619
# differential_evolution step 623: f(x)= 11.636571905722619
# differential_evolution step 624: f(x)= 11.636571905722619
# differential_evolution step 625: f(x)= 11.636571905722619
# differential_evolution step 626: f(x)= 11.636571905722619
# differential_evolution step 627: f(x)= 11.636571905722619
# differential_evolution step 628: f(x)= 11.636571905722619
# differential_evolution step 629: f(x)= 11.636571905722619
# differential_evolution step 630: f(x)= 11.636571905722619
# differential_evolution step 631: f(x)= 11.636571905722619
# differential_evolution step 632: f(x)= 11.636571905722619
# differential_evolution step 633: f(x)= 11.636571905722619
# differential_evolution step 634: f(x)= 11.636571905722619
# differential_evolution step 635: f(x)= 11.636571905722619
# differential_evolution step 636: f(x)= 11.636571905722619
# differential_evolution step 637: f(x)= 11.636571905722619
# differential_evolution step 638: f(x)= 11.636571905722619
# differential_evolution step 639: f(x)= 11.636385151418843
# differential_evolution step 640: f(x)= 11.636385151418843
# differential_evolution step 641: f(x)= 11.636385151418843
# differential_evolution step 642: f(x)= 11.636385151418843
# differential_evolution step 643: f(x)= 11.63637177795482
# differential_evolution step 644: f(x)= 11.63637177795482
# differential_evolution step 645: f(x)= 11.63637177795482
# differential_evolution step 646: f(x)= 11.63637177795482
# differential_evolution step 647: f(x)= 11.63637177795482
# differential_evolution step 648: f(x)= 11.63637177795482
# differential_evolution step 649: f(x)= 11.63637177795482
# differential_evolution step 650: f(x)= 11.63637177795482
# differential_evolution step 651: f(x)= 11.63637177795482
# differential_evolution step 652: f(x)= 11.63637177795482
# differential_evolution step 653: f(x)= 11.63637177795482
# differential_evolution step 654: f(x)= 11.63637177795482
# differential_evolution step 655: f(x)= 11.636349054826768
# differential_evolution step 656: f(x)= 11.636349054826768
# differential_evolution step 657: f(x)= 11.636349054826768
# differential_evolution step 658: f(x)= 11.636349054826768
# differential_evolution step 659: f(x)= 11.636349054826768
# differential_evolution step 660: f(x)= 11.636349054826768
# differential_evolution step 661: f(x)= 11.636349054826768
# differential_evolution step 662: f(x)= 11.636349054826768
# differential_evolution step 663: f(x)= 11.636349054826768
# differential_evolution step 664: f(x)= 11.636349054826768
# differential_evolution step 665: f(x)= 11.636349054826768
# differential_evolution step 666: f(x)= 11.636349054826768
# differential_evolution step 667: f(x)= 11.636349054826768
# differential_evolution step 668: f(x)= 11.636299864765965
# differential_evolution step 669: f(x)= 11.636299864765965
# differential_evolution step 670: f(x)= 11.636299864765965
# differential_evolution step 671: f(x)= 11.636299864765965
# differential_evolution step 672: f(x)= 11.636299864765965
# differential_evolution step 673: f(x)= 11.636299864765965
# differential_evolution step 674: f(x)= 11.636299864765965
# differential_evolution step 675: f(x)= 11.636299864765965
# differential_evolution step 676: f(x)= 11.636299864765965
# differential_evolution step 677: f(x)= 11.636299864765965
# differential_evolution step 678: f(x)= 11.636299864765965
# differential_evolution step 679: f(x)= 11.636299864765965
# differential_evolution step 680: f(x)= 11.636299864765965
# differential_evolution step 681: f(x)= 11.636264604993812
# differential_evolution step 682: f(x)= 11.636264604993812
# differential_evolution step 683: f(x)= 11.636264604993812
# differential_evolution step 684: f(x)= 11.636264604993812
# differential_evolution step 685: f(x)= 11.636264604993812
# differential_evolution step 686: f(x)= 11.636264604993812
# differential_evolution step 687: f(x)= 11.636264604993812
# differential_evolution step 688: f(x)= 11.636264604993812
# differential_evolution step 689: f(x)= 11.636264604993812
# differential_evolution step 690: f(x)= 11.636264604993812
# differential_evolution step 691: f(x)= 11.636264604993812
# differential_evolution step 692: f(x)= 11.636264604993812
# differential_evolution step 693: f(x)= 11.636264604993812
# differential_evolution step 694: f(x)= 11.636264604993812
# differential_evolution step 695: f(x)= 11.636264604993812
# differential_evolution step 696: f(x)= 11.636264604993812
# differential_evolution step 697: f(x)= 11.636157522272386
# differential_evolution step 698: f(x)= 11.635894939818986
# differential_evolution step 699: f(x)= 11.635894939818986
# differential_evolution step 700: f(x)= 11.635894939818986
# differential_evolution step 701: f(x)= 11.635894939818986
# differential_evolution step 702: f(x)= 11.635894939818986
# differential_evolution step 703: f(x)= 11.635894939818986
# differential_evolution step 704: f(x)= 11.635894939818986
# differential_evolution step 705: f(x)= 11.635894939818986
# differential_evolution step 706: f(x)= 11.635894939818986
# differential_evolution step 707: f(x)= 11.635894939818986
# differential_evolution step 708: f(x)= 11.635894939818986
# differential_evolution step 709: f(x)= 11.635894939818986
# differential_evolution step 710: f(x)= 11.635894939818986
# differential_evolution step 711: f(x)= 11.635894939818986
# differential_evolution step 712: f(x)= 11.635894939818986
# differential_evolution step 713: f(x)= 11.635894939818986
# differential_evolution step 714: f(x)= 11.635894939818986
# differential_evolution step 715: f(x)= 11.635894939818986
# differential_evolution step 716: f(x)= 11.635894939818986
# differential_evolution step 717: f(x)= 11.635894939818986
# differential_evolution step 718: f(x)= 11.635894939818986
# differential_evolution step 719: f(x)= 11.635894939818986
# differential_evolution step 720: f(x)= 11.635894939818986
# differential_evolution step 721: f(x)= 11.635894939818986
# differential_evolution step 722: f(x)= 11.635894939818986
# differential_evolution step 723: f(x)= 11.635894939818986
# differential_evolution step 724: f(x)= 11.635894939818986
# differential_evolution step 725: f(x)= 11.635894939818986
# differential_evolution step 726: f(x)= 11.635773218959024
# differential_evolution step 727: f(x)= 11.635773218959024
# differential_evolution step 728: f(x)= 11.635773218959024
# differential_evolution step 729: f(x)= 11.635773218959024
# differential_evolution step 730: f(x)= 11.635773218959024
# differential_evolution step 731: f(x)= 11.635773218959024
# differential_evolution step 732: f(x)= 11.635773218959024
# differential_evolution step 733: f(x)= 11.635773218959024
# differential_evolution step 734: f(x)= 11.63577278719475
# differential_evolution step 735: f(x)= 11.63577278719475
# differential_evolution step 736: f(x)= 11.63577278719475
# differential_evolution step 737: f(x)= 11.635693530106819
# differential_evolution step 738: f(x)= 11.635693530106819
# differential_evolution step 739: f(x)= 11.635693530106819
# differential_evolution step 740: f(x)= 11.635693530106819
# differential_evolution step 741: f(x)= 11.635693530106819
# differential_evolution step 742: f(x)= 11.635693530106819
# differential_evolution step 743: f(x)= 11.635693530106819
# differential_evolution step 744: f(x)= 11.635693530106819
# differential_evolution step 745: f(x)= 11.635693530106819
# differential_evolution step 746: f(x)= 11.635693530106819
# differential_evolution step 747: f(x)= 11.635693530106819
# differential_evolution step 748: f(x)= 11.635693530106819
# differential_evolution step 749: f(x)= 11.635693530106819
# differential_evolution step 750: f(x)= 11.635693530106819
# differential_evolution step 751: f(x)= 11.635693530106819
# differential_evolution step 752: f(x)= 11.635693530106819
# differential_evolution step 753: f(x)= 11.635693530106819
# differential_evolution step 754: f(x)= 11.635693530106819
# differential_evolution step 755: f(x)= 11.635693530106819
# differential_evolution step 756: f(x)= 11.63564236395209
# differential_evolution step 757: f(x)= 11.63564236395209
# differential_evolution step 758: f(x)= 11.63564236395209
# differential_evolution step 759: f(x)= 11.63564236395209
# differential_evolution step 760: f(x)= 11.63564236395209
# differential_evolution step 761: f(x)= 11.635613403864566
# differential_evolution step 762: f(x)= 11.635613403864566
# differential_evolution step 763: f(x)= 11.635613403864566
# differential_evolution step 764: f(x)= 11.635613403864566
# differential_evolution step 765: f(x)= 11.635613403864566
# differential_evolution step 766: f(x)= 11.635584374696379
# differential_evolution step 767: f(x)= 11.635584374696379
# differential_evolution step 768: f(x)= 11.635584374696379
# differential_evolution step 769: f(x)= 11.635584374696379
# differential_evolution step 770: f(x)= 11.635584374696379
# differential_evolution step 771: f(x)= 11.635584374696379
# differential_evolution step 772: f(x)= 11.635584374696379
# differential_evolution step 773: f(x)= 11.635584374696379
# differential_evolution step 774: f(x)= 11.635584374696379
# differential_evolution step 775: f(x)= 11.635584374696379
# differential_evolution step 776: f(x)= 11.635584374696379
# differential_evolution step 777: f(x)= 11.635568098114826
# differential_evolution step 778: f(x)= 11.635568098114826
# differential_evolution step 779: f(x)= 11.635568098114826
# differential_evolution step 780: f(x)= 11.635568098114826
# differential_evolution step 781: f(x)= 11.635568098114826
# differential_evolution step 782: f(x)= 11.635568098114826
# differential_evolution step 783: f(x)= 11.635568098114826
# differential_evolution step 784: f(x)= 11.635568098114826
# differential_evolution step 785: f(x)= 11.635568098114826
# differential_evolution step 786: f(x)= 11.635568098114826
# differential_evolution step 787: f(x)= 11.635559667078423
# differential_evolution step 788: f(x)= 11.635559667078423
# differential_evolution step 789: f(x)= 11.635559667078423
# differential_evolution step 790: f(x)= 11.635559024551677
# differential_evolution step 791: f(x)= 11.635559024551677
# differential_evolution step 792: f(x)= 11.635559024551677
# differential_evolution step 793: f(x)= 11.635559024551677
# differential_evolution step 794: f(x)= 11.635559024551677
# differential_evolution step 795: f(x)= 11.635548970864692
# differential_evolution step 796: f(x)= 11.635548970864692
# differential_evolution step 797: f(x)= 11.635548970864692
# differential_evolution step 798: f(x)= 11.635548970864692
# differential_evolution step 799: f(x)= 11.635548970864692
# differential_evolution step 800: f(x)= 11.635548970864692
# differential_evolution step 801: f(x)= 11.635548970864692
# differential_evolution step 802: f(x)= 11.635548970864692
# differential_evolution step 803: f(x)= 11.635548970864692
# differential_evolution step 804: f(x)= 11.635548970864692
# differential_evolution step 805: f(x)= 11.635548970864692
# differential_evolution step 806: f(x)= 11.635530854608215
# differential_evolution step 807: f(x)= 11.635530854608215
# differential_evolution step 808: f(x)= 11.635530854608215
# differential_evolution step 809: f(x)= 11.635530854608215
# differential_evolution step 810: f(x)= 11.635530854608215
# differential_evolution step 811: f(x)= 11.635530854608215
# differential_evolution step 812: f(x)= 11.635530854608215
# differential_evolution step 813: f(x)= 11.635530854608215
# differential_evolution step 814: f(x)= 11.635530854608215
# differential_evolution step 815: f(x)= 11.635530854608215
# differential_evolution step 816: f(x)= 11.635530854608215
# differential_evolution step 817: f(x)= 11.635530854608215
# differential_evolution step 818: f(x)= 11.635522887551035
# differential_evolution step 819: f(x)= 11.635522887551035
# differential_evolution step 820: f(x)= 11.635522887551035
# differential_evolution step 821: f(x)= 11.635520333369449
# differential_evolution step 822: f(x)= 11.635520333369449
# differential_evolution step 823: f(x)= 11.63550594081434
# differential_evolution step 824: f(x)= 11.63550594081434
# differential_evolution step 825: f(x)= 11.63550594081434
# differential_evolution step 826: f(x)= 11.63550594081434
# differential_evolution step 827: f(x)= 11.63550594081434
# differential_evolution step 828: f(x)= 11.63550594081434
# differential_evolution step 829: f(x)= 11.63550594081434
# differential_evolution step 830: f(x)= 11.63550594081434
# differential_evolution step 831: f(x)= 11.63550594081434
# differential_evolution step 832: f(x)= 11.63550594081434
# differential_evolution step 833: f(x)= 11.63550594081434
# differential_evolution step 834: f(x)= 11.63550594081434
# differential_evolution step 835: f(x)= 11.63550178353961
# differential_evolution step 836: f(x)= 11.63550178353961
# differential_evolution step 837: f(x)= 11.63550178353961
# differential_evolution step 838: f(x)= 11.63550178353961
# differential_evolution step 839: f(x)= 11.63550178353961
# differential_evolution step 840: f(x)= 11.63550178353961
# differential_evolution step 841: f(x)= 11.63550178353961
# differential_evolution step 842: f(x)= 11.63550178353961
# differential_evolution step 843: f(x)= 11.63550178353961
# differential_evolution step 844: f(x)= 11.63550178353961
# differential_evolution step 845: f(x)= 11.63550178353961
# differential_evolution step 846: f(x)= 11.63550178353961
# differential_evolution step 847: f(x)= 11.63550178353961
# differential_evolution step 848: f(x)= 11.63550178353961
# differential_evolution step 849: f(x)= 11.63550178353961
# differential_evolution step 850: f(x)= 11.635497693558463
# differential_evolution step 851: f(x)= 11.635497693558463
# differential_evolution step 852: f(x)= 11.635497693558463
# differential_evolution step 853: f(x)= 11.635497693558463
# differential_evolution step 854: f(x)= 11.635497693558463
# differential_evolution step 855: f(x)= 11.635491916301842
# differential_evolution step 856: f(x)= 11.635491916301842
# differential_evolution step 857: f(x)= 11.635491916301842
# differential_evolution step 858: f(x)= 11.635491916301842
# differential_evolution step 859: f(x)= 11.635491916301842
# differential_evolution step 860: f(x)= 11.635491916301842
# differential_evolution step 861: f(x)= 11.635491916301842
# differential_evolution step 862: f(x)= 11.635491916301842
# differential_evolution step 863: f(x)= 11.635491916301842
# differential_evolution step 864: f(x)= 11.635491916301842
# differential_evolution step 865: f(x)= 11.635491916301842
# differential_evolution step 866: f(x)= 11.635491916301842
# differential_evolution step 867: f(x)= 11.635491916301842
# differential_evolution step 868: f(x)= 11.635491916301842
# differential_evolution step 869: f(x)= 11.635491916301842
# differential_evolution step 870: f(x)= 11.635491916301842
# differential_evolution step 871: f(x)= 11.635491916301842
# differential_evolution step 872: f(x)= 11.635483660854574
# differential_evolution step 873: f(x)= 11.635483660854574
# differential_evolution step 874: f(x)= 11.635483660854574
# differential_evolution step 875: f(x)= 11.635483660854574
# differential_evolution step 876: f(x)= 11.635483660854574
# differential_evolution step 877: f(x)= 11.635483660854574
# differential_evolution step 878: f(x)= 11.635483660854574
# differential_evolution step 879: f(x)= 11.635483660854574
# differential_evolution step 880: f(x)= 11.635483660854574
# differential_evolution step 881: f(x)= 11.635483660854574
# differential_evolution step 882: f(x)= 11.635483660854574
# differential_evolution step 883: f(x)= 11.635483660854574
# differential_evolution step 884: f(x)= 11.635483660854574
# differential_evolution step 885: f(x)= 11.635481850120136
# differential_evolution step 886: f(x)= 11.635481850120136
# differential_evolution step 887: f(x)= 11.635481850120136
# differential_evolution step 888: f(x)= 11.635481850120136
# differential_evolution step 889: f(x)= 11.635481850120136
# differential_evolution step 890: f(x)= 11.635481850120136
# differential_evolution step 891: f(x)= 11.63547408782861
# differential_evolution step 892: f(x)= 11.63547408782861
# differential_evolution step 893: f(x)= 11.63547408782861
# differential_evolution step 894: f(x)= 11.63547408782861
# differential_evolution step 895: f(x)= 11.63547408782861
# differential_evolution step 896: f(x)= 11.63547408782861
# differential_evolution step 897: f(x)= 11.63547408782861
# differential_evolution step 898: f(x)= 11.63547408782861
# differential_evolution step 899: f(x)= 11.63547408782861
# differential_evolution step 900: f(x)= 11.63547408782861
# differential_evolution step 901: f(x)= 11.63547408782861
# differential_evolution step 902: f(x)= 11.63547408782861
# differential_evolution step 903: f(x)= 11.63547408782861
# differential_evolution step 904: f(x)= 11.63547408782861
# differential_evolution step 905: f(x)= 11.63547408782861
# differential_evolution step 906: f(x)= 11.63547408782861
# differential_evolution step 907: f(x)= 11.63547408782861
# differential_evolution step 908: f(x)= 11.63547408782861
# differential_evolution step 909: f(x)= 11.63547408782861
# differential_evolution step 910: f(x)= 11.63547408782861
# differential_evolution step 911: f(x)= 11.63547408782861
# differential_evolution step 912: f(x)= 11.63547408782861
# differential_evolution step 913: f(x)= 11.63547408782861
# differential_evolution step 914: f(x)= 11.63547408782861
# differential_evolution step 915: f(x)= 11.63547408782861
# differential_evolution step 916: f(x)= 11.63547408782861
# differential_evolution step 917: f(x)= 11.63547408782861
# differential_evolution step 918: f(x)= 11.635471912577005
# differential_evolution step 919: f(x)= 11.635471912577005
# differential_evolution step 920: f(x)= 11.635471912577005
# differential_evolution step 921: f(x)= 11.635471912577005
# differential_evolution step 922: f(x)= 11.635471912577005
# differential_evolution step 923: f(x)= 11.635471912577005
# differential_evolution step 924: f(x)= 11.635471912577005
# differential_evolution step 925: f(x)= 11.635471912577005
# differential_evolution step 926: f(x)= 11.635471912577005
# differential_evolution step 927: f(x)= 11.635471912577005
# differential_evolution step 928: f(x)= 11.635471912577005
# differential_evolution step 929: f(x)= 11.635471912577005
# differential_evolution step 930: f(x)= 11.635471912577005
# differential_evolution step 931: f(x)= 11.635471912577005
# differential_evolution step 932: f(x)= 11.635471912577005
# differential_evolution step 933: f(x)= 11.635471912577005
# differential_evolution step 934: f(x)= 11.635471912577005
# differential_evolution step 935: f(x)= 11.635471912577005
# differential_evolution step 936: f(x)= 11.635471912577005
# differential_evolution step 937: f(x)= 11.635471912577005
# differential_evolution step 938: f(x)= 11.635471912577005
# differential_evolution step 939: f(x)= 11.635471601580237
# differential_evolution step 940: f(x)= 11.635471492122107
# differential_evolution step 941: f(x)= 11.635470635194702
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=7.9923, r_e=3.0576, n=0.8191, x_0=39.9281
# Sérsic 2: I_e=0.5583, r_e=16.7985, n=1.5040, x_0=48.9007
# Sérsic 3: I_e=0.9817, r_e=3.5485, n=1.1996, x_0=58.1217
# Chi quadro minimo: 11.635465898686952
# True

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Sérsic 1: I_e=7.9923, r_e=3.0576, n=0.8191, x_0=39.9281
# Sérsic 2: I_e=0.5583, r_e=16.7985, n=1.5040, x_0=48.9007
# Sérsic 3: I_e=0.9817, r_e=3.5485, n=1.1996, x_0=58.1217
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=6.2250, r_e=3.6075, n=1.0145, x_0=40.1565
# Sérsic 2: I_e=0.2184, r_e=24.1291, n=2.1472, x_0=49.1327
# Sérsic 3: I_e=0.9689, r_e=4.5611, n=1.1801, x_0=58.1217
# [0.48238145 0.16092649 0.06748037 0.05566851 0.07712568 4.7763331
#  0.27027462 0.12830471 0.23262905 0.80901315 0.18539645 0.10269027]
# 1.8623156735286088

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 1368.3067055156391
# differential_evolution step 2: f(x)= 1368.3067055156391
# differential_evolution step 3: f(x)= 1368.3067055156391
# differential_evolution step 4: f(x)= 1368.3067055156391
# differential_evolution step 5: f(x)= 1026.3530602635979
# differential_evolution step 6: f(x)= 911.8840907225268
# differential_evolution step 7: f(x)= 911.8840907225268
# differential_evolution step 8: f(x)= 697.3682612879188
# differential_evolution step 9: f(x)= 423.6586209774131
# differential_evolution step 10: f(x)= 423.6586209774131
# differential_evolution step 11: f(x)= 423.6586209774131
# differential_evolution step 12: f(x)= 423.6586209774131
# differential_evolution step 13: f(x)= 387.3045079515681
# differential_evolution step 14: f(x)= 387.3045079515681
# differential_evolution step 15: f(x)= 306.53929444486386
# differential_evolution step 16: f(x)= 306.53929444486386
# differential_evolution step 17: f(x)= 306.53929444486386
# differential_evolution step 18: f(x)= 306.53929444486386
# differential_evolution step 19: f(x)= 306.53929444486386
# differential_evolution step 20: f(x)= 271.8275446550143
# differential_evolution step 21: f(x)= 234.45690211391678
# differential_evolution step 22: f(x)= 234.14363491409742
# differential_evolution step 23: f(x)= 234.14363491409742
# differential_evolution step 24: f(x)= 234.14363491409742
# differential_evolution step 25: f(x)= 234.14363491409742
# differential_evolution step 26: f(x)= 234.14363491409742
# differential_evolution step 27: f(x)= 234.14363491409742
# differential_evolution step 28: f(x)= 234.14363491409742
# differential_evolution step 29: f(x)= 222.5848969843798
# differential_evolution step 30: f(x)= 213.16339693036443
# differential_evolution step 31: f(x)= 213.16339693036443
# differential_evolution step 32: f(x)= 213.16339693036443
# differential_evolution step 33: f(x)= 213.16339693036443
# differential_evolution step 34: f(x)= 213.16339693036443
# differential_evolution step 35: f(x)= 213.16339693036443
# differential_evolution step 36: f(x)= 213.16339693036443
# differential_evolution step 37: f(x)= 213.07760590948266
# differential_evolution step 38: f(x)= 184.88026799775767
# differential_evolution step 39: f(x)= 184.88026799775767
# differential_evolution step 40: f(x)= 184.88026799775767
# differential_evolution step 41: f(x)= 184.88026799775767
# differential_evolution step 42: f(x)= 184.88026799775767
# differential_evolution step 43: f(x)= 180.2556960729661
# differential_evolution step 44: f(x)= 180.2556960729661
# differential_evolution step 45: f(x)= 180.2556960729661
# differential_evolution step 46: f(x)= 180.2556960729661
# differential_evolution step 47: f(x)= 180.2556960729661
# differential_evolution step 48: f(x)= 180.2556960729661
# differential_evolution step 49: f(x)= 175.80404868460025
# differential_evolution step 50: f(x)= 175.80404868460025
# differential_evolution step 51: f(x)= 167.57638117661284
# differential_evolution step 52: f(x)= 167.57638117661284
# differential_evolution step 53: f(x)= 167.57638117661284
# differential_evolution step 54: f(x)= 167.57638117661284
# differential_evolution step 55: f(x)= 167.57638117661284
# differential_evolution step 56: f(x)= 156.95771677039346
# differential_evolution step 57: f(x)= 156.95771677039346
# differential_evolution step 58: f(x)= 156.95771677039346
# differential_evolution step 59: f(x)= 156.95771677039346
# differential_evolution step 60: f(x)= 156.95771677039346
# differential_evolution step 61: f(x)= 156.95771677039346
# differential_evolution step 62: f(x)= 142.6955311189755
# differential_evolution step 63: f(x)= 142.6955311189755
# differential_evolution step 64: f(x)= 142.6955311189755
# differential_evolution step 65: f(x)= 142.6955311189755
# differential_evolution step 66: f(x)= 142.6955311189755
# differential_evolution step 67: f(x)= 136.54623269408
# differential_evolution step 68: f(x)= 136.54623269408
# differential_evolution step 69: f(x)= 135.52504024308737
# differential_evolution step 70: f(x)= 127.0872752732956
# differential_evolution step 71: f(x)= 127.0872752732956
# differential_evolution step 72: f(x)= 127.0872752732956
# differential_evolution step 73: f(x)= 127.05811257519754
# differential_evolution step 74: f(x)= 119.27668924127047
# differential_evolution step 75: f(x)= 119.27668924127047
# differential_evolution step 76: f(x)= 119.27668924127047
# differential_evolution step 77: f(x)= 110.57587330903847
# differential_evolution step 78: f(x)= 103.5041239108525
# differential_evolution step 79: f(x)= 103.5041239108525
# differential_evolution step 80: f(x)= 103.5041239108525
# differential_evolution step 81: f(x)= 103.5041239108525
# differential_evolution step 82: f(x)= 99.710516721344
# differential_evolution step 83: f(x)= 99.710516721344
# differential_evolution step 84: f(x)= 99.710516721344
# differential_evolution step 85: f(x)= 99.710516721344
# differential_evolution step 86: f(x)= 99.710516721344
# differential_evolution step 87: f(x)= 99.710516721344
# differential_evolution step 88: f(x)= 99.710516721344
# differential_evolution step 89: f(x)= 92.79524220757696
# differential_evolution step 90: f(x)= 92.79524220757696
# differential_evolution step 91: f(x)= 91.90271579771098
# differential_evolution step 92: f(x)= 88.93241525344514
# differential_evolution step 93: f(x)= 88.93241525344514
# differential_evolution step 94: f(x)= 88.93241525344514
# differential_evolution step 95: f(x)= 88.93241525344514
# differential_evolution step 96: f(x)= 88.93241525344514
# differential_evolution step 97: f(x)= 88.93241525344514
# differential_evolution step 98: f(x)= 84.3114643180148
# differential_evolution step 99: f(x)= 84.3114643180148
# differential_evolution step 100: f(x)= 84.3114643180148
# differential_evolution step 101: f(x)= 84.3114643180148
# differential_evolution step 102: f(x)= 84.3114643180148
# differential_evolution step 103: f(x)= 84.3114643180148
# differential_evolution step 104: f(x)= 84.3114643180148
# differential_evolution step 105: f(x)= 84.3114643180148
# differential_evolution step 106: f(x)= 84.1758120463978
# differential_evolution step 107: f(x)= 84.1758120463978
# differential_evolution step 108: f(x)= 84.1758120463978
# differential_evolution step 109: f(x)= 83.41075166007585
# differential_evolution step 110: f(x)= 83.41075166007585
# differential_evolution step 111: f(x)= 83.41075166007585
# differential_evolution step 112: f(x)= 83.41075166007585
# differential_evolution step 113: f(x)= 83.29709249652852
# differential_evolution step 114: f(x)= 83.29709249652852
# differential_evolution step 115: f(x)= 82.56873061878305
# differential_evolution step 116: f(x)= 82.56873061878305
# differential_evolution step 117: f(x)= 81.44843985430654
# differential_evolution step 118: f(x)= 81.44843985430654
# differential_evolution step 119: f(x)= 81.44843985430654
# differential_evolution step 120: f(x)= 81.44843985430654
# differential_evolution step 121: f(x)= 81.44843985430654
# differential_evolution step 122: f(x)= 81.44843985430654
# differential_evolution step 123: f(x)= 81.44843985430654
# differential_evolution step 124: f(x)= 80.87900875224898
# differential_evolution step 125: f(x)= 80.87900875224898
# differential_evolution step 126: f(x)= 80.33688829398322
# differential_evolution step 127: f(x)= 80.33688829398322
# differential_evolution step 128: f(x)= 79.2968381171278
# differential_evolution step 129: f(x)= 79.2968381171278
# differential_evolution step 130: f(x)= 79.2968381171278
# differential_evolution step 131: f(x)= 79.2968381171278
# differential_evolution step 132: f(x)= 79.2968381171278
# differential_evolution step 133: f(x)= 79.2968381171278
# differential_evolution step 134: f(x)= 79.2968381171278
# differential_evolution step 135: f(x)= 79.2968381171278
# differential_evolution step 136: f(x)= 79.2968381171278
# differential_evolution step 137: f(x)= 79.2968381171278
# differential_evolution step 138: f(x)= 79.19834203167753
# differential_evolution step 139: f(x)= 79.19834203167753
# differential_evolution step 140: f(x)= 79.19834203167753
# differential_evolution step 141: f(x)= 79.19834203167753
# differential_evolution step 142: f(x)= 79.19834203167753
# differential_evolution step 143: f(x)= 79.19834203167753
# differential_evolution step 144: f(x)= 79.14510795152775
# differential_evolution step 145: f(x)= 78.03148749834462
# differential_evolution step 146: f(x)= 78.03148749834462
# differential_evolution step 147: f(x)= 77.8298310756467
# differential_evolution step 148: f(x)= 77.8298310756467
# differential_evolution step 149: f(x)= 77.47418430651035
# differential_evolution step 150: f(x)= 77.47418430651035
# differential_evolution step 151: f(x)= 77.21651934979951
# differential_evolution step 152: f(x)= 77.15755103904124
# differential_evolution step 153: f(x)= 77.15755103904124
# differential_evolution step 154: f(x)= 77.15755103904124
# differential_evolution step 155: f(x)= 77.15755103904124
# differential_evolution step 156: f(x)= 77.1383292401442
# differential_evolution step 157: f(x)= 77.1383292401442
# differential_evolution step 158: f(x)= 76.88044002690187
# differential_evolution step 159: f(x)= 76.88044002690187
# differential_evolution step 160: f(x)= 76.88044002690187
# differential_evolution step 161: f(x)= 76.88044002690187
# differential_evolution step 162: f(x)= 76.88044002690187
# differential_evolution step 163: f(x)= 76.88044002690187
# differential_evolution step 164: f(x)= 76.88044002690187
# differential_evolution step 165: f(x)= 76.79256861716314
# differential_evolution step 166: f(x)= 76.79256861716314
# differential_evolution step 167: f(x)= 76.79256861716314
# differential_evolution step 168: f(x)= 76.79256861716314
# differential_evolution step 169: f(x)= 76.52099382876492
# differential_evolution step 170: f(x)= 76.52099382876492
# differential_evolution step 171: f(x)= 76.52099382876492
# differential_evolution step 172: f(x)= 76.52099382876492
# differential_evolution step 173: f(x)= 76.26023286634695
# differential_evolution step 174: f(x)= 76.26023286634695
# differential_evolution step 175: f(x)= 76.26023286634695
# differential_evolution step 176: f(x)= 76.26023286634695
# differential_evolution step 177: f(x)= 76.26023286634695
# differential_evolution step 178: f(x)= 76.26023286634695
# differential_evolution step 179: f(x)= 76.26023286634695
# differential_evolution step 180: f(x)= 76.26023286634695
# differential_evolution step 181: f(x)= 76.26023286634695
# differential_evolution step 182: f(x)= 76.26023286634695
# differential_evolution step 183: f(x)= 76.26023286634695
# differential_evolution step 184: f(x)= 76.26023286634695
# differential_evolution step 185: f(x)= 76.17894862775387
# differential_evolution step 186: f(x)= 76.17894862775387
# differential_evolution step 187: f(x)= 76.17894862775387
# differential_evolution step 188: f(x)= 76.17894862775387
# differential_evolution step 189: f(x)= 76.17894862775387
# differential_evolution step 190: f(x)= 76.17894862775387
# differential_evolution step 191: f(x)= 76.17894862775387
# differential_evolution step 192: f(x)= 76.17894862775387
# differential_evolution step 193: f(x)= 76.17894862775387
# differential_evolution step 194: f(x)= 76.00851967285486
# differential_evolution step 195: f(x)= 76.00851967285486
# differential_evolution step 196: f(x)= 76.00851967285486
# differential_evolution step 197: f(x)= 76.00851967285486
# differential_evolution step 198: f(x)= 76.00275806892898
# differential_evolution step 199: f(x)= 76.00275806892898
# differential_evolution step 200: f(x)= 76.00275806892898
# differential_evolution step 201: f(x)= 76.00275806892898
# differential_evolution step 202: f(x)= 76.00275806892898
# differential_evolution step 203: f(x)= 76.00275806892898
# differential_evolution step 204: f(x)= 76.00275806892898
# differential_evolution step 205: f(x)= 76.00275806892898
# differential_evolution step 206: f(x)= 76.00275806892898
# differential_evolution step 207: f(x)= 76.00275806892898
# differential_evolution step 208: f(x)= 76.00275806892898
# differential_evolution step 209: f(x)= 76.00275806892898
# differential_evolution step 210: f(x)= 76.00275806892898
# differential_evolution step 211: f(x)= 76.00275806892898
# differential_evolution step 212: f(x)= 76.00275806892898
# differential_evolution step 213: f(x)= 75.98850798769372
# differential_evolution step 214: f(x)= 75.98850798769372
# differential_evolution step 215: f(x)= 75.98850798769372
# differential_evolution step 216: f(x)= 75.98850798769372
# differential_evolution step 217: f(x)= 75.98850798769372
# differential_evolution step 218: f(x)= 75.98850798769372
# differential_evolution step 219: f(x)= 75.92997013523888
# differential_evolution step 220: f(x)= 75.92997013523888
# differential_evolution step 221: f(x)= 75.92997013523888
# differential_evolution step 222: f(x)= 75.92997013523888
# differential_evolution step 223: f(x)= 75.92997013523888
# differential_evolution step 224: f(x)= 75.92997013523888
# differential_evolution step 225: f(x)= 75.92997013523888
# differential_evolution step 226: f(x)= 75.9087405589147
# differential_evolution step 227: f(x)= 75.9087405589147
# differential_evolution step 228: f(x)= 75.9087405589147
# differential_evolution step 229: f(x)= 75.9087405589147
# differential_evolution step 230: f(x)= 75.9087405589147
# differential_evolution step 231: f(x)= 75.87507895783673
# differential_evolution step 232: f(x)= 75.84521542130851
# differential_evolution step 233: f(x)= 75.84489358785166
# differential_evolution step 234: f(x)= 75.84489358785166
# differential_evolution step 235: f(x)= 75.84489358785166
# differential_evolution step 236: f(x)= 75.84489358785166
# differential_evolution step 237: f(x)= 75.84489358785166
# differential_evolution step 238: f(x)= 75.84489358785166
# differential_evolution step 239: f(x)= 75.84489358785166
# differential_evolution step 240: f(x)= 75.84489358785166
# differential_evolution step 241: f(x)= 75.84489358785166
# differential_evolution step 242: f(x)= 75.84489358785166
# differential_evolution step 243: f(x)= 75.84489358785166
# differential_evolution step 244: f(x)= 75.84489358785166
# differential_evolution step 245: f(x)= 75.84489358785166
# differential_evolution step 246: f(x)= 75.84489358785166
# differential_evolution step 247: f(x)= 75.84489358785166
# differential_evolution step 248: f(x)= 75.84489358785166
# differential_evolution step 249: f(x)= 75.84489358785166
# differential_evolution step 250: f(x)= 75.84489358785166
# differential_evolution step 251: f(x)= 75.84489358785166
# differential_evolution step 252: f(x)= 75.84489358785166
# differential_evolution step 253: f(x)= 75.84489358785166
# differential_evolution step 254: f(x)= 75.84489358785166
# differential_evolution step 255: f(x)= 75.84489358785166
# differential_evolution step 256: f(x)= 75.84489358785166
# differential_evolution step 257: f(x)= 75.84489358785166
# differential_evolution step 258: f(x)= 75.84489358785166
# differential_evolution step 259: f(x)= 75.84489358785166
# differential_evolution step 260: f(x)= 75.83897778312183
# differential_evolution step 261: f(x)= 75.81767053009168
# differential_evolution step 262: f(x)= 75.81767053009168
# differential_evolution step 263: f(x)= 75.81767053009168
# differential_evolution step 264: f(x)= 75.81767053009168
# differential_evolution step 265: f(x)= 75.81767053009168
# differential_evolution step 266: f(x)= 75.81767053009168
# differential_evolution step 267: f(x)= 75.81767053009168
# differential_evolution step 268: f(x)= 75.81767053009168
# differential_evolution step 269: f(x)= 75.81767053009168
# differential_evolution step 270: f(x)= 75.81767053009168
# differential_evolution step 271: f(x)= 75.81767053009168
# differential_evolution step 272: f(x)= 75.81767053009168
# differential_evolution step 273: f(x)= 75.81767053009168
# differential_evolution step 274: f(x)= 75.81767053009168
# differential_evolution step 275: f(x)= 75.81767053009168
# differential_evolution step 276: f(x)= 75.81767053009168
# differential_evolution step 277: f(x)= 75.81767053009168
# differential_evolution step 278: f(x)= 75.81767053009168
# differential_evolution step 279: f(x)= 75.81767053009168
# differential_evolution step 280: f(x)= 75.81767053009168
# differential_evolution step 281: f(x)= 75.81767053009168
# differential_evolution step 282: f(x)= 75.81767053009168
# differential_evolution step 283: f(x)= 75.81767053009168
# differential_evolution step 284: f(x)= 75.81767053009168
# differential_evolution step 285: f(x)= 75.81767053009168
# differential_evolution step 286: f(x)= 75.81767053009168
# differential_evolution step 287: f(x)= 75.81767053009168
# differential_evolution step 288: f(x)= 75.81767053009168
# differential_evolution step 289: f(x)= 75.81767053009168
# differential_evolution step 290: f(x)= 75.81767053009168
# differential_evolution step 291: f(x)= 75.79110596596007
# differential_evolution step 292: f(x)= 75.79030677215995
# differential_evolution step 293: f(x)= 75.79030677215995
# differential_evolution step 294: f(x)= 75.79030677215995
# differential_evolution step 295: f(x)= 75.79030677215995
# differential_evolution step 296: f(x)= 75.79030677215995
# differential_evolution step 297: f(x)= 75.79030677215995
# differential_evolution step 298: f(x)= 75.79030677215995
# differential_evolution step 299: f(x)= 75.79030677215995
# differential_evolution step 300: f(x)= 75.79030677215995
# differential_evolution step 301: f(x)= 75.79030677215995
# differential_evolution step 302: f(x)= 75.7883508112781
# differential_evolution step 303: f(x)= 75.7883508112781
# differential_evolution step 304: f(x)= 75.7883508112781
# differential_evolution step 305: f(x)= 75.7422800922168
# differential_evolution step 306: f(x)= 75.7422800922168
# differential_evolution step 307: f(x)= 75.7422800922168
# differential_evolution step 308: f(x)= 75.7422800922168
# differential_evolution step 309: f(x)= 75.7422800922168
# differential_evolution step 310: f(x)= 75.7422800922168
# differential_evolution step 311: f(x)= 75.7422800922168
# differential_evolution step 312: f(x)= 75.7422800922168
# differential_evolution step 313: f(x)= 75.7422800922168
# differential_evolution step 314: f(x)= 75.7422800922168
# differential_evolution step 315: f(x)= 75.7422800922168
# differential_evolution step 316: f(x)= 75.7422800922168
# differential_evolution step 317: f(x)= 75.7422800922168
# differential_evolution step 318: f(x)= 75.7422800922168
# differential_evolution step 319: f(x)= 75.7422800922168
# differential_evolution step 320: f(x)= 75.7422800922168
# differential_evolution step 321: f(x)= 75.7422800922168
# differential_evolution step 322: f(x)= 75.7422800922168
# differential_evolution step 323: f(x)= 75.7422800922168
# differential_evolution step 324: f(x)= 75.7422800922168
# differential_evolution step 325: f(x)= 75.7422800922168
# differential_evolution step 326: f(x)= 75.7422800922168
# differential_evolution step 327: f(x)= 75.73738085861608
# differential_evolution step 328: f(x)= 75.73738085861608
# differential_evolution step 329: f(x)= 75.73738085861608
# differential_evolution step 330: f(x)= 75.73738085861608
# differential_evolution step 331: f(x)= 75.73738085861608
# differential_evolution step 332: f(x)= 75.73738085861608
# differential_evolution step 333: f(x)= 75.73738085861608
# differential_evolution step 334: f(x)= 75.73738085861608
# differential_evolution step 335: f(x)= 75.73738085861608
# differential_evolution step 336: f(x)= 75.73738085861608
# differential_evolution step 337: f(x)= 75.73738085861608
# differential_evolution step 338: f(x)= 75.73738085861608
# differential_evolution step 339: f(x)= 75.73738085861608
# differential_evolution step 340: f(x)= 75.73738085861608
# differential_evolution step 341: f(x)= 75.73738085861608
# differential_evolution step 342: f(x)= 75.73738085861608
# differential_evolution step 343: f(x)= 75.73738085861608
# differential_evolution step 344: f(x)= 75.73738085861608
# differential_evolution step 345: f(x)= 75.73738085861608
# differential_evolution step 346: f(x)= 75.73738085861608
# differential_evolution step 347: f(x)= 75.73738085861608
# differential_evolution step 348: f(x)= 75.73738085861608
# differential_evolution step 349: f(x)= 75.73738085861608
# differential_evolution step 350: f(x)= 75.73738085861608
# differential_evolution step 351: f(x)= 75.73738085861608
# differential_evolution step 352: f(x)= 75.73738085861608
# differential_evolution step 353: f(x)= 75.73738085861608
# differential_evolution step 354: f(x)= 75.73738085861608
# differential_evolution step 355: f(x)= 75.73738085861608
# differential_evolution step 356: f(x)= 75.73738085861608
# differential_evolution step 357: f(x)= 75.73738085861608
# differential_evolution step 358: f(x)= 75.73738085861608
# differential_evolution step 359: f(x)= 75.73738085861608
# differential_evolution step 360: f(x)= 75.73738085861608
# differential_evolution step 361: f(x)= 75.73738085861608
# differential_evolution step 362: f(x)= 75.73738085861608
# differential_evolution step 363: f(x)= 75.73738085861608
# differential_evolution step 364: f(x)= 75.73738085861608
# differential_evolution step 365: f(x)= 75.73738085861608
# differential_evolution step 366: f(x)= 75.73738085861608
# differential_evolution step 367: f(x)= 75.73738085861608
# differential_evolution step 368: f(x)= 75.73738085861608
# differential_evolution step 369: f(x)= 75.73738085861608
# differential_evolution step 370: f(x)= 75.73738085861608
# differential_evolution step 371: f(x)= 75.73738085861608
# differential_evolution step 372: f(x)= 75.73738085861608
# differential_evolution step 373: f(x)= 75.73738085861608
# differential_evolution step 374: f(x)= 75.73738085861608
# differential_evolution step 375: f(x)= 75.73738085861608
# differential_evolution step 376: f(x)= 75.73738085861608
# differential_evolution step 377: f(x)= 75.73738085861608
# differential_evolution step 378: f(x)= 75.73738085861608
# differential_evolution step 379: f(x)= 75.73738085861608
# differential_evolution step 380: f(x)= 75.73738085861608
# differential_evolution step 381: f(x)= 75.73738085861608
# differential_evolution step 382: f(x)= 75.73738085861608
# differential_evolution step 383: f(x)= 75.73738085861608
# differential_evolution step 384: f(x)= 75.73738085861608
# differential_evolution step 385: f(x)= 75.73738085861608
# differential_evolution step 386: f(x)= 75.73738085861608
# differential_evolution step 387: f(x)= 75.73738085861608
# differential_evolution step 388: f(x)= 75.73738085861608
# differential_evolution step 389: f(x)= 75.73738085861608
# differential_evolution step 390: f(x)= 75.73738085861608
# differential_evolution step 391: f(x)= 75.73738085861608
# differential_evolution step 392: f(x)= 75.73738085861608
# differential_evolution step 393: f(x)= 75.73738085861608
# differential_evolution step 394: f(x)= 75.73738085861608
# differential_evolution step 395: f(x)= 75.73738085861608
# differential_evolution step 396: f(x)= 75.73738085861608
# differential_evolution step 397: f(x)= 75.73738085861608
# differential_evolution step 398: f(x)= 75.73738085861608
# differential_evolution step 399: f(x)= 75.73551279783378
# differential_evolution step 400: f(x)= 75.73551279783378
# differential_evolution step 401: f(x)= 75.73551279783378
# differential_evolution step 402: f(x)= 75.73551279783378
# differential_evolution step 403: f(x)= 75.73551279783378
# differential_evolution step 404: f(x)= 75.73551279783378
# differential_evolution step 405: f(x)= 75.73551279783378
# differential_evolution step 406: f(x)= 75.73551279783378
# differential_evolution step 407: f(x)= 75.73551279783378
# differential_evolution step 408: f(x)= 75.73551279783378
# differential_evolution step 409: f(x)= 75.73551279783378
# differential_evolution step 410: f(x)= 75.73551279783378
# differential_evolution step 411: f(x)= 75.73551279783378
# differential_evolution step 412: f(x)= 75.73551279783378
# differential_evolution step 413: f(x)= 75.73551279783378
# differential_evolution step 414: f(x)= 75.73551279783378
# differential_evolution step 415: f(x)= 75.73551279783378
# differential_evolution step 416: f(x)= 75.73551279783378
# differential_evolution step 417: f(x)= 75.73551279783378
# differential_evolution step 418: f(x)= 75.73551279783378
# differential_evolution step 419: f(x)= 75.73551279783378
# differential_evolution step 420: f(x)= 75.73551279783378
# differential_evolution step 421: f(x)= 75.73551279783378
# differential_evolution step 422: f(x)= 75.73551279783378
# differential_evolution step 423: f(x)= 75.73551279783378
# differential_evolution step 424: f(x)= 75.73551279783378
# differential_evolution step 425: f(x)= 75.73551279783378
# differential_evolution step 426: f(x)= 75.73551279783378
# differential_evolution step 427: f(x)= 75.73551279783378
# differential_evolution step 428: f(x)= 75.73551279783378
# differential_evolution step 429: f(x)= 75.732603197311
# differential_evolution step 430: f(x)= 75.732603197311
# differential_evolution step 431: f(x)= 75.732603197311
# differential_evolution step 432: f(x)= 75.732603197311
# differential_evolution step 433: f(x)= 75.732603197311
# differential_evolution step 434: f(x)= 75.732603197311
# differential_evolution step 435: f(x)= 75.732603197311
# differential_evolution step 436: f(x)= 75.732603197311
# differential_evolution step 437: f(x)= 75.732603197311
# differential_evolution step 438: f(x)= 75.732603197311
# differential_evolution step 439: f(x)= 75.732603197311
# differential_evolution step 440: f(x)= 75.732603197311
# differential_evolution step 441: f(x)= 75.732603197311
# differential_evolution step 442: f(x)= 75.732603197311
# differential_evolution step 443: f(x)= 75.732603197311
# differential_evolution step 444: f(x)= 75.732603197311
# differential_evolution step 445: f(x)= 75.732603197311
# differential_evolution step 446: f(x)= 75.732603197311
# differential_evolution step 447: f(x)= 75.732603197311
# differential_evolution step 448: f(x)= 75.732603197311
# differential_evolution step 449: f(x)= 75.732603197311
# differential_evolution step 450: f(x)= 75.732603197311
# differential_evolution step 451: f(x)= 75.732603197311
# differential_evolution step 452: f(x)= 75.732603197311
# differential_evolution step 453: f(x)= 75.732603197311
# differential_evolution step 454: f(x)= 75.732603197311
# differential_evolution step 455: f(x)= 75.732603197311
# differential_evolution step 456: f(x)= 75.732603197311
# differential_evolution step 457: f(x)= 75.732603197311
# differential_evolution step 458: f(x)= 75.732603197311
# differential_evolution step 459: f(x)= 75.732603197311
# differential_evolution step 460: f(x)= 75.732603197311
# differential_evolution step 461: f(x)= 75.732603197311
# differential_evolution step 462: f(x)= 75.732603197311
# differential_evolution step 463: f(x)= 75.732603197311
# differential_evolution step 464: f(x)= 75.732603197311
# differential_evolution step 465: f(x)= 75.732603197311
# differential_evolution step 466: f(x)= 75.732603197311
# differential_evolution step 467: f(x)= 75.732603197311
# differential_evolution step 468: f(x)= 75.732603197311
# differential_evolution step 469: f(x)= 75.732603197311
# differential_evolution step 470: f(x)= 75.732603197311
# differential_evolution step 471: f(x)= 75.732603197311
# differential_evolution step 472: f(x)= 75.732603197311
# differential_evolution step 473: f(x)= 75.732603197311
# differential_evolution step 474: f(x)= 75.732603197311
# differential_evolution step 475: f(x)= 75.732603197311
# differential_evolution step 476: f(x)= 75.732603197311
# differential_evolution step 477: f(x)= 75.732603197311
# differential_evolution step 478: f(x)= 75.732603197311
# differential_evolution step 479: f(x)= 75.732603197311
# differential_evolution step 480: f(x)= 75.732603197311
# differential_evolution step 481: f(x)= 75.72240607203065
# differential_evolution step 482: f(x)= 75.72240607203065
# differential_evolution step 483: f(x)= 75.72240607203065
# differential_evolution step 484: f(x)= 75.72240607203065
# differential_evolution step 485: f(x)= 75.72240607203065
# differential_evolution step 486: f(x)= 75.72240607203065
# differential_evolution step 487: f(x)= 75.72240607203065
# differential_evolution step 488: f(x)= 75.72240607203065
# differential_evolution step 489: f(x)= 75.72240607203065
# differential_evolution step 490: f(x)= 75.72240607203065
# differential_evolution step 491: f(x)= 75.72240607203065
# differential_evolution step 492: f(x)= 75.72240607203065
# differential_evolution step 493: f(x)= 75.72240607203065
# differential_evolution step 494: f(x)= 75.72240607203065
# differential_evolution step 495: f(x)= 75.72240607203065
# differential_evolution step 496: f(x)= 75.72240607203065
# differential_evolution step 497: f(x)= 75.72240607203065
# differential_evolution step 498: f(x)= 75.72240607203065
# differential_evolution step 499: f(x)= 75.72240607203065
# differential_evolution step 500: f(x)= 75.72240607203065
# differential_evolution step 501: f(x)= 75.72240607203065
# differential_evolution step 502: f(x)= 75.72240607203065
# differential_evolution step 503: f(x)= 75.72240607203065
# differential_evolution step 504: f(x)= 75.72240607203065
# differential_evolution step 505: f(x)= 75.72240607203065
# differential_evolution step 506: f(x)= 75.72240607203065
# differential_evolution step 507: f(x)= 75.72240607203065
# differential_evolution step 508: f(x)= 75.72240607203065
# differential_evolution step 509: f(x)= 75.72240607203065
# differential_evolution step 510: f(x)= 75.72240607203065
# differential_evolution step 511: f(x)= 75.70792056271588
# differential_evolution step 512: f(x)= 75.70792056271588
# differential_evolution step 513: f(x)= 75.70792056271588
# differential_evolution step 514: f(x)= 75.70792056271588
# differential_evolution step 515: f(x)= 75.70792056271588
# differential_evolution step 516: f(x)= 75.70792056271588
# differential_evolution step 517: f(x)= 75.70792056271588
# differential_evolution step 518: f(x)= 75.70792056271588
# differential_evolution step 519: f(x)= 75.70792056271588
# differential_evolution step 520: f(x)= 75.70792056271588
# differential_evolution step 521: f(x)= 75.70792056271588
# differential_evolution step 522: f(x)= 75.70792056271588
# differential_evolution step 523: f(x)= 75.70792056271588
# differential_evolution step 524: f(x)= 75.70792056271588
# differential_evolution step 525: f(x)= 75.70792056271588
# differential_evolution step 526: f(x)= 75.70792056271588
# differential_evolution step 527: f(x)= 75.70792056271588
# differential_evolution step 528: f(x)= 75.70792056271588
# differential_evolution step 529: f(x)= 75.70792056271588
# differential_evolution step 530: f(x)= 75.70792056271588
# differential_evolution step 531: f(x)= 75.70792056271588
# differential_evolution step 532: f(x)= 75.70792056271588
# differential_evolution step 533: f(x)= 75.70792056271588
# differential_evolution step 534: f(x)= 75.70792056271588
# differential_evolution step 535: f(x)= 75.70792056271588
# differential_evolution step 536: f(x)= 75.70792056271588
# differential_evolution step 537: f(x)= 75.70792056271588
# differential_evolution step 538: f(x)= 75.70792056271588
# differential_evolution step 539: f(x)= 75.70792056271588
# differential_evolution step 540: f(x)= 75.70792056271588
# differential_evolution step 541: f(x)= 75.70792056271588
# differential_evolution step 542: f(x)= 75.70792056271588
# differential_evolution step 543: f(x)= 75.70792056271588
# differential_evolution step 544: f(x)= 75.70792056271588
# differential_evolution step 545: f(x)= 75.70792056271588
# differential_evolution step 546: f(x)= 75.70792056271588
# differential_evolution step 547: f(x)= 75.70792056271588
# differential_evolution step 548: f(x)= 75.70792056271588
# differential_evolution step 549: f(x)= 75.70792056271588
# differential_evolution step 550: f(x)= 75.70792056271588
# differential_evolution step 551: f(x)= 75.70563599075518
# differential_evolution step 552: f(x)= 75.70563599075518
# differential_evolution step 553: f(x)= 75.70563599075518
# differential_evolution step 554: f(x)= 75.70563599075518
# differential_evolution step 555: f(x)= 75.70563599075518
# differential_evolution step 556: f(x)= 75.70272967625407
# differential_evolution step 557: f(x)= 75.70272967625407
# differential_evolution step 558: f(x)= 75.70272967625407
# differential_evolution step 559: f(x)= 75.70272967625407
# differential_evolution step 560: f(x)= 75.70272967625407
# differential_evolution step 561: f(x)= 75.70272967625407
# differential_evolution step 562: f(x)= 75.70272967625407
# differential_evolution step 563: f(x)= 75.70272967625407
# differential_evolution step 564: f(x)= 75.70272967625407
# differential_evolution step 565: f(x)= 75.70272967625407
# differential_evolution step 566: f(x)= 75.70272967625407
# differential_evolution step 567: f(x)= 75.70272967625407
# differential_evolution step 568: f(x)= 75.70272967625407
# differential_evolution step 569: f(x)= 75.70272967625407
# differential_evolution step 570: f(x)= 75.70272967625407
# differential_evolution step 571: f(x)= 75.70272967625407
# differential_evolution step 572: f(x)= 75.70272967625407
# differential_evolution step 573: f(x)= 75.70272967625407
# differential_evolution step 574: f(x)= 75.70272967625407
# differential_evolution step 575: f(x)= 75.70272967625407
# differential_evolution step 576: f(x)= 75.70272967625407
# differential_evolution step 577: f(x)= 75.70272967625407
# differential_evolution step 578: f(x)= 75.70272967625407
# differential_evolution step 579: f(x)= 75.70272967625407
# differential_evolution step 580: f(x)= 75.70272967625407
# differential_evolution step 581: f(x)= 75.70272967625407
# differential_evolution step 582: f(x)= 75.70272967625407
# differential_evolution step 583: f(x)= 75.70272967625407
# differential_evolution step 584: f(x)= 75.70272967625407
# differential_evolution step 585: f(x)= 75.70272967625407
# differential_evolution step 586: f(x)= 75.70272967625407
# differential_evolution step 587: f(x)= 75.70272967625407
# differential_evolution step 588: f(x)= 75.70272967625407
# differential_evolution step 589: f(x)= 75.70272967625407
# differential_evolution step 590: f(x)= 75.70272967625407
# differential_evolution step 591: f(x)= 75.70272967625407
# differential_evolution step 592: f(x)= 75.70272967625407
# differential_evolution step 593: f(x)= 75.70272967625407
# differential_evolution step 594: f(x)= 75.70272967625407
# differential_evolution step 595: f(x)= 75.70272967625407
# differential_evolution step 596: f(x)= 75.70272967625407
# differential_evolution step 597: f(x)= 75.70272967625407
# differential_evolution step 598: f(x)= 75.70272967625407
# differential_evolution step 599: f(x)= 75.70272967625407
# differential_evolution step 600: f(x)= 75.70272967625407
# differential_evolution step 601: f(x)= 75.70272967625407
# differential_evolution step 602: f(x)= 75.70272967625407
# differential_evolution step 603: f(x)= 75.70272967625407
# differential_evolution step 604: f(x)= 75.70272967625407
# differential_evolution step 605: f(x)= 75.70272967625407
# differential_evolution step 606: f(x)= 75.70272967625407
# differential_evolution step 607: f(x)= 75.70272967625407
# differential_evolution step 608: f(x)= 75.70272967625407
# differential_evolution step 609: f(x)= 75.70272967625407
# differential_evolution step 610: f(x)= 75.70272967625407
# differential_evolution step 611: f(x)= 75.70272967625407
# differential_evolution step 612: f(x)= 75.70272967625407
# differential_evolution step 613: f(x)= 75.70272967625407
# differential_evolution step 614: f(x)= 75.70272967625407
# differential_evolution step 615: f(x)= 75.70272967625407
# differential_evolution step 616: f(x)= 75.70272967625407
# differential_evolution step 617: f(x)= 75.70272967625407
# differential_evolution step 618: f(x)= 75.70272967625407
# differential_evolution step 619: f(x)= 75.70272967625407
# differential_evolution step 620: f(x)= 75.70272967625407
# differential_evolution step 621: f(x)= 75.70272967625407
# differential_evolution step 622: f(x)= 75.70272967625407
# differential_evolution step 623: f(x)= 75.70272967625407
# differential_evolution step 624: f(x)= 75.70272967625407
# differential_evolution step 625: f(x)= 75.70272967625407
# differential_evolution step 626: f(x)= 75.70272967625407
# differential_evolution step 627: f(x)= 75.70272967625407
# differential_evolution step 628: f(x)= 75.70272967625407
# differential_evolution step 629: f(x)= 75.70272967625407
# differential_evolution step 630: f(x)= 75.70272967625407
# differential_evolution step 631: f(x)= 75.70272967625407
# differential_evolution step 632: f(x)= 75.70272967625407
# differential_evolution step 633: f(x)= 75.70272967625407
# differential_evolution step 634: f(x)= 75.70272967625407
# differential_evolution step 635: f(x)= 75.70272967625407
# differential_evolution step 636: f(x)= 75.70272967625407
# differential_evolution step 637: f(x)= 75.70272967625407
# differential_evolution step 638: f(x)= 75.70272967625407
# differential_evolution step 639: f(x)= 75.70272967625407
# differential_evolution step 640: f(x)= 75.70272967625407
# differential_evolution step 641: f(x)= 75.70272967625407
# differential_evolution step 642: f(x)= 75.70272967625407
# differential_evolution step 643: f(x)= 75.70272967625407
# differential_evolution step 644: f(x)= 75.70272967625407
# differential_evolution step 645: f(x)= 75.70272967625407
# differential_evolution step 646: f(x)= 75.70272967625407
# differential_evolution step 647: f(x)= 75.70272967625407
# differential_evolution step 648: f(x)= 75.70272967625407
# differential_evolution step 649: f(x)= 75.70272967625407
# differential_evolution step 650: f(x)= 75.70272967625407
# differential_evolution step 651: f(x)= 75.70272967625407
# differential_evolution step 652: f(x)= 75.70272967625407
# differential_evolution step 653: f(x)= 75.70272967625407
# differential_evolution step 654: f(x)= 75.70272967625407
# differential_evolution step 655: f(x)= 75.70272967625407
# differential_evolution step 656: f(x)= 75.70272967625407
# differential_evolution step 657: f(x)= 75.70272967625407
# differential_evolution step 658: f(x)= 75.70272967625407
# differential_evolution step 659: f(x)= 75.70272967625407
# differential_evolution step 660: f(x)= 75.70272967625407
# differential_evolution step 661: f(x)= 75.70272967625407
# differential_evolution step 662: f(x)= 75.70272967625407
# differential_evolution step 663: f(x)= 75.70272967625407
# differential_evolution step 664: f(x)= 75.70272967625407
# differential_evolution step 665: f(x)= 75.70272967625407
# differential_evolution step 666: f(x)= 75.70272967625407
# differential_evolution step 667: f(x)= 75.70272967625407
# differential_evolution step 668: f(x)= 75.70272967625407
# differential_evolution step 669: f(x)= 75.70272967625407
# differential_evolution step 670: f(x)= 75.70272967625407
# differential_evolution step 671: f(x)= 75.70272967625407
# differential_evolution step 672: f(x)= 75.70272967625407
# differential_evolution step 673: f(x)= 75.70272967625407
# differential_evolution step 674: f(x)= 75.70272967625407
# differential_evolution step 675: f(x)= 75.70272967625407
# differential_evolution step 676: f(x)= 75.70272967625407
# differential_evolution step 677: f(x)= 75.70272967625407
# differential_evolution step 678: f(x)= 75.70272967625407
# differential_evolution step 679: f(x)= 75.70272967625407
# differential_evolution step 680: f(x)= 75.70272967625407
# differential_evolution step 681: f(x)= 75.70272967625407
# differential_evolution step 682: f(x)= 75.70272967625407
# differential_evolution step 683: f(x)= 75.70272967625407
# differential_evolution step 684: f(x)= 75.70272967625407
# differential_evolution step 685: f(x)= 75.70272967625407
# differential_evolution step 686: f(x)= 75.70272967625407
# differential_evolution step 687: f(x)= 75.69903167853764
# differential_evolution step 688: f(x)= 75.69903167853764
# differential_evolution step 689: f(x)= 75.69903167853764
# differential_evolution step 690: f(x)= 75.69903167853764
# differential_evolution step 691: f(x)= 75.69903167853764
# differential_evolution step 692: f(x)= 75.69903167853764
# differential_evolution step 693: f(x)= 75.69903167853764
# differential_evolution step 694: f(x)= 75.69903167853764
# differential_evolution step 695: f(x)= 75.69903167853764
# differential_evolution step 696: f(x)= 75.69903167853764
# differential_evolution step 697: f(x)= 75.69903167853764
# differential_evolution step 698: f(x)= 75.69903167853764
# differential_evolution step 699: f(x)= 75.69903167853764
# differential_evolution step 700: f(x)= 75.69903167853764
# differential_evolution step 701: f(x)= 75.69903167853764
# differential_evolution step 702: f(x)= 75.69903167853764
# differential_evolution step 703: f(x)= 75.69903167853764
# differential_evolution step 704: f(x)= 75.69903167853764
# differential_evolution step 705: f(x)= 75.69903167853764
# differential_evolution step 706: f(x)= 75.69903167853764
# differential_evolution step 707: f(x)= 75.69903167853764
# differential_evolution step 708: f(x)= 75.69903167853764
# differential_evolution step 709: f(x)= 75.69903167853764
# differential_evolution step 710: f(x)= 75.69903167853764
# differential_evolution step 711: f(x)= 75.69903167853764
# differential_evolution step 712: f(x)= 75.69690999688397
# differential_evolution step 713: f(x)= 75.69690999688397
# differential_evolution step 714: f(x)= 75.69690999688397
# differential_evolution step 715: f(x)= 75.69690999688397
# differential_evolution step 716: f(x)= 75.69690999688397
# differential_evolution step 717: f(x)= 75.69690999688397
# differential_evolution step 718: f(x)= 75.69690999688397
# differential_evolution step 719: f(x)= 75.69690999688397
# differential_evolution step 720: f(x)= 75.69690999688397
# differential_evolution step 721: f(x)= 75.69690999688397
# differential_evolution step 722: f(x)= 75.69690999688397
# differential_evolution step 723: f(x)= 75.69690999688397
# differential_evolution step 724: f(x)= 75.69690999688397
# differential_evolution step 725: f(x)= 75.69690999688397
# differential_evolution step 726: f(x)= 75.69690999688397
# differential_evolution step 727: f(x)= 75.69690999688397
# differential_evolution step 728: f(x)= 75.69690999688397
# differential_evolution step 729: f(x)= 75.69690999688397
# differential_evolution step 730: f(x)= 75.69690999688397
# differential_evolution step 731: f(x)= 75.69690999688397
# differential_evolution step 732: f(x)= 75.69690999688397
# differential_evolution step 733: f(x)= 75.69690999688397
# differential_evolution step 734: f(x)= 75.69690999688397
# differential_evolution step 735: f(x)= 75.69690999688397
# differential_evolution step 736: f(x)= 75.69690999688397
# differential_evolution step 737: f(x)= 75.6946149799352
# differential_evolution step 738: f(x)= 75.6946149799352
# differential_evolution step 739: f(x)= 75.6946149799352
# differential_evolution step 740: f(x)= 75.6946149799352
# differential_evolution step 741: f(x)= 75.6946149799352
# differential_evolution step 742: f(x)= 75.6946149799352
# differential_evolution step 743: f(x)= 75.6946149799352
# differential_evolution step 744: f(x)= 75.6946149799352
# differential_evolution step 745: f(x)= 75.6946149799352
# differential_evolution step 746: f(x)= 75.69378285413437
# differential_evolution step 747: f(x)= 75.69378285413437
# differential_evolution step 748: f(x)= 75.69378285413437
# differential_evolution step 749: f(x)= 75.69378285413437
# differential_evolution step 750: f(x)= 75.69316501556268
# differential_evolution step 751: f(x)= 75.69316501556268
# differential_evolution step 752: f(x)= 75.69316501556268
# differential_evolution step 753: f(x)= 75.69316501556268
# differential_evolution step 754: f(x)= 75.69316501556268
# differential_evolution step 755: f(x)= 75.69316501556268
# differential_evolution step 756: f(x)= 75.69316501556268
# differential_evolution step 757: f(x)= 75.69316501556268
# differential_evolution step 758: f(x)= 75.69316501556268
# differential_evolution step 759: f(x)= 75.69316501556268
# differential_evolution step 760: f(x)= 75.69316501556268
# differential_evolution step 761: f(x)= 75.69316501556268
# differential_evolution step 762: f(x)= 75.69283249539724
# differential_evolution step 763: f(x)= 75.69283249539724
# differential_evolution step 764: f(x)= 75.69143135930652
# differential_evolution step 765: f(x)= 75.69143135930652
# differential_evolution step 766: f(x)= 75.69143135930652
# differential_evolution step 767: f(x)= 75.69143135930652
# differential_evolution step 768: f(x)= 75.69143135930652
# differential_evolution step 769: f(x)= 75.69143135930652
# differential_evolution step 770: f(x)= 75.6912438058046
# differential_evolution step 771: f(x)= 75.6912438058046
# differential_evolution step 772: f(x)= 75.6912438058046
# differential_evolution step 773: f(x)= 75.6912438058046
# differential_evolution step 774: f(x)= 75.6912438058046
# differential_evolution step 775: f(x)= 75.6912438058046
# differential_evolution step 776: f(x)= 75.6912438058046
# differential_evolution step 777: f(x)= 75.6912438058046
# differential_evolution step 778: f(x)= 75.6912438058046
# differential_evolution step 779: f(x)= 75.6912438058046
# differential_evolution step 780: f(x)= 75.6912438058046
# differential_evolution step 781: f(x)= 75.6912438058046
# differential_evolution step 782: f(x)= 75.6912438058046
# differential_evolution step 783: f(x)= 75.6912438058046
# differential_evolution step 784: f(x)= 75.6912438058046
# differential_evolution step 785: f(x)= 75.6912438058046
# differential_evolution step 786: f(x)= 75.6912438058046
# differential_evolution step 787: f(x)= 75.6912438058046
# differential_evolution step 788: f(x)= 75.6912438058046
# differential_evolution step 789: f(x)= 75.6912438058046
# differential_evolution step 790: f(x)= 75.69073928788292
# differential_evolution step 791: f(x)= 75.69051931424566
# differential_evolution step 792: f(x)= 75.69026844107522
# differential_evolution step 793: f(x)= 75.69026844107522
# differential_evolution step 794: f(x)= 75.69026844107522
# differential_evolution step 795: f(x)= 75.69026844107522
# differential_evolution step 796: f(x)= 75.68950038171393
# differential_evolution step 797: f(x)= 75.68950038171393
# differential_evolution step 798: f(x)= 75.68950038171393
# differential_evolution step 799: f(x)= 75.68950038171393
# differential_evolution step 800: f(x)= 75.68950038171393
# differential_evolution step 801: f(x)= 75.68950038171393
# differential_evolution step 802: f(x)= 75.68950038171393
# differential_evolution step 803: f(x)= 75.68950038171393
# differential_evolution step 804: f(x)= 75.68950038171393
# differential_evolution step 805: f(x)= 75.68808911236663
# differential_evolution step 806: f(x)= 75.68808911236663
# differential_evolution step 807: f(x)= 75.68808911236663
# differential_evolution step 808: f(x)= 75.68808911236663
# differential_evolution step 809: f(x)= 75.68808911236663
# differential_evolution step 810: f(x)= 75.68808911236663
# differential_evolution step 811: f(x)= 75.68808911236663
# differential_evolution step 812: f(x)= 75.68808911236663
# differential_evolution step 813: f(x)= 75.68808911236663
# differential_evolution step 814: f(x)= 75.68808911236663
# differential_evolution step 815: f(x)= 75.68808911236663
# differential_evolution step 816: f(x)= 75.68808911236663
# differential_evolution step 817: f(x)= 75.68807647906283
# differential_evolution step 818: f(x)= 75.68807647906283
# differential_evolution step 819: f(x)= 75.68807647906283
# differential_evolution step 820: f(x)= 75.68807647906283
# differential_evolution step 821: f(x)= 75.68794257195616
# differential_evolution step 822: f(x)= 75.68794257195616
# differential_evolution step 823: f(x)= 75.68794257195616
# differential_evolution step 824: f(x)= 75.68789209817479
# differential_evolution step 825: f(x)= 75.68789209817479
# differential_evolution step 826: f(x)= 75.68789209817479
# differential_evolution step 827: f(x)= 75.68789209817479
# differential_evolution step 828: f(x)= 75.68789209817479
# differential_evolution step 829: f(x)= 75.68707111217277
# differential_evolution step 830: f(x)= 75.68707111217277
# differential_evolution step 831: f(x)= 75.68707111217277
# differential_evolution step 832: f(x)= 75.68707111217277
# differential_evolution step 833: f(x)= 75.68707111217277
# differential_evolution step 834: f(x)= 75.68707111217277
# differential_evolution step 835: f(x)= 75.68707111217277
# differential_evolution step 836: f(x)= 75.68707111217277
# differential_evolution step 837: f(x)= 75.68707111217277
# differential_evolution step 838: f(x)= 75.68707111217277
# differential_evolution step 839: f(x)= 75.68707111217277
# differential_evolution step 840: f(x)= 75.68707111217277
# differential_evolution step 841: f(x)= 75.68707111217277
# differential_evolution step 842: f(x)= 75.68707111217277
# differential_evolution step 843: f(x)= 75.68707111217277
# differential_evolution step 844: f(x)= 75.68707111217277
# differential_evolution step 845: f(x)= 75.68707111217277
# differential_evolution step 846: f(x)= 75.68707111217277
# differential_evolution step 847: f(x)= 75.68691748961182
# differential_evolution step 848: f(x)= 75.68691748961182
# differential_evolution step 849: f(x)= 75.68691748961182
# differential_evolution step 850: f(x)= 75.68691748961182
# differential_evolution step 851: f(x)= 75.68691748961182
# differential_evolution step 852: f(x)= 75.68691748961182
# differential_evolution step 853: f(x)= 75.68691748961182
# differential_evolution step 854: f(x)= 75.68691748961182
# differential_evolution step 855: f(x)= 75.68691748961182
# differential_evolution step 856: f(x)= 75.68691748961182
# differential_evolution step 857: f(x)= 75.68691748961182
# differential_evolution step 858: f(x)= 75.68691748961182
# differential_evolution step 859: f(x)= 75.68691748961182
# differential_evolution step 860: f(x)= 75.68691748961182
# differential_evolution step 861: f(x)= 75.68691748961182
# differential_evolution step 862: f(x)= 75.68676504025562
# differential_evolution step 863: f(x)= 75.68676504025562
# differential_evolution step 864: f(x)= 75.68676504025562
# differential_evolution step 865: f(x)= 75.68655072305903
# differential_evolution step 866: f(x)= 75.68653938180114
# differential_evolution step 867: f(x)= 75.68653938180114
# differential_evolution step 868: f(x)= 75.68653938180114
# differential_evolution step 869: f(x)= 75.68653938180114
# differential_evolution step 870: f(x)= 75.68653938180114
# differential_evolution step 871: f(x)= 75.68653938180114
# differential_evolution step 872: f(x)= 75.68653938180114
# differential_evolution step 873: f(x)= 75.68653938180114
# differential_evolution step 874: f(x)= 75.68570261219621
# differential_evolution step 875: f(x)= 75.68570261219621
# differential_evolution step 876: f(x)= 75.68570261219621
# differential_evolution step 877: f(x)= 75.68570261219621
# differential_evolution step 878: f(x)= 75.68570261219621
# differential_evolution step 879: f(x)= 75.68570261219621
# differential_evolution step 880: f(x)= 75.68570261219621
# differential_evolution step 881: f(x)= 75.68570261219621
# differential_evolution step 882: f(x)= 75.68570261219621
# differential_evolution step 883: f(x)= 75.68570261219621
# differential_evolution step 884: f(x)= 75.68570261219621
# differential_evolution step 885: f(x)= 75.68570261219621
# differential_evolution step 886: f(x)= 75.68570261219621
# differential_evolution step 887: f(x)= 75.68570261219621
# differential_evolution step 888: f(x)= 75.68570261219621
# differential_evolution step 889: f(x)= 75.68570261219621
# differential_evolution step 890: f(x)= 75.68570261219621
# differential_evolution step 891: f(x)= 75.68570261219621
# differential_evolution step 892: f(x)= 75.68498908786471
# differential_evolution step 893: f(x)= 75.68498908786471
# differential_evolution step 894: f(x)= 75.68498908786471
# differential_evolution step 895: f(x)= 75.68498908786471
# differential_evolution step 896: f(x)= 75.68498908786471
# differential_evolution step 897: f(x)= 75.68498908786471
# differential_evolution step 898: f(x)= 75.68498908786471
# differential_evolution step 899: f(x)= 75.68498908786471
# differential_evolution step 900: f(x)= 75.68498908786471
# differential_evolution step 901: f(x)= 75.68498908786471
# differential_evolution step 902: f(x)= 75.68498908786471
# differential_evolution step 903: f(x)= 75.68498908786471
# differential_evolution step 904: f(x)= 75.68498908786471
# differential_evolution step 905: f(x)= 75.68498908786471
# differential_evolution step 906: f(x)= 75.68498908786471
# differential_evolution step 907: f(x)= 75.68498908786471
# differential_evolution step 908: f(x)= 75.68498908786471
# differential_evolution step 909: f(x)= 75.68498908786471
# differential_evolution step 910: f(x)= 75.68498908786471
# differential_evolution step 911: f(x)= 75.68498908786471
# differential_evolution step 912: f(x)= 75.68498908786471
# differential_evolution step 913: f(x)= 75.68498908786471
# differential_evolution step 914: f(x)= 75.68498908786471
# differential_evolution step 915: f(x)= 75.68498908786471
# differential_evolution step 916: f(x)= 75.68498908786471
# differential_evolution step 917: f(x)= 75.68498908786471
# differential_evolution step 918: f(x)= 75.68498908786471
# differential_evolution step 919: f(x)= 75.68498908786471
# differential_evolution step 920: f(x)= 75.68498908786471
# differential_evolution step 921: f(x)= 75.68498908786471
# differential_evolution step 922: f(x)= 75.68498908786471
# differential_evolution step 923: f(x)= 75.68498908786471
# differential_evolution step 924: f(x)= 75.68498908786471
# differential_evolution step 925: f(x)= 75.68498908786471
# differential_evolution step 926: f(x)= 75.68498908786471
# differential_evolution step 927: f(x)= 75.68498908786471
# differential_evolution step 928: f(x)= 75.68498908786471
# differential_evolution step 929: f(x)= 75.68498908786471
# differential_evolution step 930: f(x)= 75.68498908786471
# differential_evolution step 931: f(x)= 75.68498908786471
# differential_evolution step 932: f(x)= 75.68480591940035
# differential_evolution step 933: f(x)= 75.68480591940035
# differential_evolution step 934: f(x)= 75.68480591940035
# differential_evolution step 935: f(x)= 75.68480591940035
# differential_evolution step 936: f(x)= 75.68480591940035
# differential_evolution step 937: f(x)= 75.68480591940035
# differential_evolution step 938: f(x)= 75.68480591940035
# differential_evolution step 939: f(x)= 75.68480591940035
# differential_evolution step 940: f(x)= 75.68480591940035
# differential_evolution step 941: f(x)= 75.68480591940035
# differential_evolution step 942: f(x)= 75.68480591940035
# differential_evolution step 943: f(x)= 75.68480591940035
# differential_evolution step 944: f(x)= 75.68480591940035
# differential_evolution step 945: f(x)= 75.68480591940035
# differential_evolution step 946: f(x)= 75.68480591940035
# differential_evolution step 947: f(x)= 75.68480591940035
# differential_evolution step 948: f(x)= 75.68480591940035
# differential_evolution step 949: f(x)= 75.68480591940035
# differential_evolution step 950: f(x)= 75.68480591940035
# differential_evolution step 951: f(x)= 75.68480591940035
# differential_evolution step 952: f(x)= 75.68480591940035
# differential_evolution step 953: f(x)= 75.68480591940035
# differential_evolution step 954: f(x)= 75.68480591940035
# differential_evolution step 955: f(x)= 75.68480591940035
# differential_evolution step 956: f(x)= 75.68480591940035
# differential_evolution step 957: f(x)= 75.68480591940035
# differential_evolution step 958: f(x)= 75.68480591940035
# differential_evolution step 959: f(x)= 75.68480591940035
# differential_evolution step 960: f(x)= 75.68480591940035
# differential_evolution step 961: f(x)= 75.68480591940035
# differential_evolution step 962: f(x)= 75.68480591940035
# differential_evolution step 963: f(x)= 75.68480591940035
# differential_evolution step 964: f(x)= 75.68480591940035
# differential_evolution step 965: f(x)= 75.68480591940035
# differential_evolution step 966: f(x)= 75.68480591940035
# differential_evolution step 967: f(x)= 75.68480591940035
# differential_evolution step 968: f(x)= 75.6847579966176
# differential_evolution step 969: f(x)= 75.6847579966176
# differential_evolution step 970: f(x)= 75.6847579966176
# differential_evolution step 971: f(x)= 75.6847579966176
# differential_evolution step 972: f(x)= 75.6847579966176
# differential_evolution step 973: f(x)= 75.6847579966176
# differential_evolution step 974: f(x)= 75.6847579966176
# differential_evolution step 975: f(x)= 75.6847579966176
# differential_evolution step 976: f(x)= 75.6847579966176
# differential_evolution step 977: f(x)= 75.6847579966176
# differential_evolution step 978: f(x)= 75.6847579966176
# differential_evolution step 979: f(x)= 75.6847579966176
# differential_evolution step 980: f(x)= 75.6847579966176
# differential_evolution step 981: f(x)= 75.6847579966176
# differential_evolution step 982: f(x)= 75.6847579966176
# differential_evolution step 983: f(x)= 75.6847579966176
# differential_evolution step 984: f(x)= 75.6847579966176
# differential_evolution step 985: f(x)= 75.68470017240503
# differential_evolution step 986: f(x)= 75.68470017240503
# differential_evolution step 987: f(x)= 75.68470017240503
# differential_evolution step 988: f(x)= 75.68470017240503
# differential_evolution step 989: f(x)= 75.68461661572132
# differential_evolution step 990: f(x)= 75.68461661572132
# differential_evolution step 991: f(x)= 75.68456468328489
# differential_evolution step 992: f(x)= 75.68456468328489
# differential_evolution step 993: f(x)= 75.68456468328489
# differential_evolution step 994: f(x)= 75.68456468328489
# differential_evolution step 995: f(x)= 75.68456468328489
# differential_evolution step 996: f(x)= 75.68456468328489
# differential_evolution step 997: f(x)= 75.68443774747146
# differential_evolution step 998: f(x)= 75.68443774747146
# differential_evolution step 999: f(x)= 75.68443774747146
# differential_evolution step 1000: f(x)= 75.68441220971783
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=3.5251, n=1.0409, x_0=39.3295
# Sérsic 2: I_e=6.0692, r_e=9.8348, n=0.1000, x_0=49.0671
# Sérsic 3: I_e=1.3157, r_e=0.0101, n=3.8777, x_0=57.1866
# Chi quadro minimo: 75.68438773989219
# False
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_9692\2399396679.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

# %%
# Plots:
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Sérsic 1: I_e=10.0000, r_e=3.5251, n=1.0409, x_0=39.3295
# Sérsic 2: I_e=6.0692, r_e=9.8348, n=0.1000, x_0=49.0671
# Sérsic 3: I_e=1.3157, r_e=0.0101, n=3.8777, x_0=57.1866
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = real_errors_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=10.0000, r_e=3.3838, n=1.1441, x_0=39.8159
# Sérsic 2: I_e=0.7956, r_e=13.7774, n=1.6579, x_0=48.7750
# Sérsic 3: I_e=1.5325, r_e=3.8152, n=1.0498, x_0=57.2605
# [0.79476238 0.13899653 0.073694   0.06831882 0.17729089 1.21970849
#  0.17973361 0.14143672 0.29522032 0.53527095 0.15929644 0.12599086]
# 3.3392308597429388

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[3])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 1476.0919675855966
# differential_evolution step 2: f(x)= 1476.0919675855966
# differential_evolution step 3: f(x)= 1476.0919675855966
# differential_evolution step 4: f(x)= 893.5674957893593
# differential_evolution step 5: f(x)= 419.6166368383908
# differential_evolution step 6: f(x)= 419.6166368383908
# differential_evolution step 7: f(x)= 419.6166368383908
# differential_evolution step 8: f(x)= 333.43847898706883
# differential_evolution step 9: f(x)= 333.43847898706883
# differential_evolution step 10: f(x)= 285.8965675544328
# differential_evolution step 11: f(x)= 285.8965675544328
# differential_evolution step 12: f(x)= 285.8965675544328
# differential_evolution step 13: f(x)= 285.8965675544328
# differential_evolution step 14: f(x)= 285.8965675544328
# differential_evolution step 15: f(x)= 193.6721113352888
# differential_evolution step 16: f(x)= 193.6721113352888
# differential_evolution step 17: f(x)= 193.6721113352888
# differential_evolution step 18: f(x)= 149.30292286855644
# differential_evolution step 19: f(x)= 146.46523896018607
# differential_evolution step 20: f(x)= 146.46523896018607
# differential_evolution step 21: f(x)= 146.46523896018607
# differential_evolution step 22: f(x)= 146.46523896018607
# differential_evolution step 23: f(x)= 105.55929775363319
# differential_evolution step 24: f(x)= 105.55929775363319
# differential_evolution step 25: f(x)= 105.55929775363319
# differential_evolution step 26: f(x)= 56.55684719773695
# differential_evolution step 27: f(x)= 56.55684719773695
# differential_evolution step 28: f(x)= 56.55684719773695
# differential_evolution step 29: f(x)= 56.55684719773695
# differential_evolution step 30: f(x)= 56.55684719773695
# differential_evolution step 31: f(x)= 56.55684719773695
# differential_evolution step 32: f(x)= 56.55684719773695
# differential_evolution step 33: f(x)= 56.55684719773695
# differential_evolution step 34: f(x)= 56.55684719773695
# differential_evolution step 35: f(x)= 37.00023163506476
# differential_evolution step 36: f(x)= 37.00023163506476
# differential_evolution step 37: f(x)= 37.00023163506476
# differential_evolution step 38: f(x)= 37.00023163506476
# differential_evolution step 39: f(x)= 37.00023163506476
# differential_evolution step 40: f(x)= 33.3012208027352
# differential_evolution step 41: f(x)= 33.3012208027352
# differential_evolution step 42: f(x)= 33.3012208027352
# differential_evolution step 43: f(x)= 33.3012208027352
# differential_evolution step 44: f(x)= 33.3012208027352
# differential_evolution step 45: f(x)= 28.38096959797199
# differential_evolution step 46: f(x)= 28.38096959797199
# differential_evolution step 47: f(x)= 28.38096959797199
# differential_evolution step 48: f(x)= 28.38096959797199
# differential_evolution step 49: f(x)= 28.38096959797199
# differential_evolution step 50: f(x)= 28.38096959797199
# differential_evolution step 51: f(x)= 28.38096959797199
# differential_evolution step 52: f(x)= 28.38096959797199
# differential_evolution step 53: f(x)= 28.38096959797199
# differential_evolution step 54: f(x)= 28.38096959797199
# differential_evolution step 55: f(x)= 28.38096959797199
# differential_evolution step 56: f(x)= 28.38096959797199
# differential_evolution step 57: f(x)= 28.38096959797199
# differential_evolution step 58: f(x)= 28.38096959797199
# differential_evolution step 59: f(x)= 28.38096959797199
# differential_evolution step 60: f(x)= 28.38096959797199
# differential_evolution step 61: f(x)= 20.062591587568686
# differential_evolution step 62: f(x)= 20.062591587568686
# differential_evolution step 63: f(x)= 20.062591587568686
# differential_evolution step 64: f(x)= 20.062591587568686
# differential_evolution step 65: f(x)= 20.062591587568686
# differential_evolution step 66: f(x)= 20.062591587568686
# differential_evolution step 67: f(x)= 20.062591587568686
# differential_evolution step 68: f(x)= 18.43139868656427
# differential_evolution step 69: f(x)= 18.43139868656427
# differential_evolution step 70: f(x)= 18.43139868656427
# differential_evolution step 71: f(x)= 18.43139868656427
# differential_evolution step 72: f(x)= 18.43139868656427
# differential_evolution step 73: f(x)= 18.43139868656427
# differential_evolution step 74: f(x)= 18.43139868656427
# differential_evolution step 75: f(x)= 18.43139868656427
# differential_evolution step 76: f(x)= 18.43139868656427
# differential_evolution step 77: f(x)= 18.43139868656427
# differential_evolution step 78: f(x)= 18.43139868656427
# differential_evolution step 79: f(x)= 17.72040676183728
# differential_evolution step 80: f(x)= 17.72040676183728
# differential_evolution step 81: f(x)= 17.72040676183728
# differential_evolution step 82: f(x)= 17.283246857397653
# differential_evolution step 83: f(x)= 13.788514285148802
# differential_evolution step 84: f(x)= 13.788514285148802
# differential_evolution step 85: f(x)= 13.788514285148802
# differential_evolution step 86: f(x)= 10.443082568630212
# differential_evolution step 87: f(x)= 10.443082568630212
# differential_evolution step 88: f(x)= 10.443082568630212
# differential_evolution step 89: f(x)= 10.443082568630212
# differential_evolution step 90: f(x)= 10.443082568630212
# differential_evolution step 91: f(x)= 9.765427318782708
# differential_evolution step 92: f(x)= 9.765427318782708
# differential_evolution step 93: f(x)= 9.765427318782708
# differential_evolution step 94: f(x)= 9.765427318782708
# differential_evolution step 95: f(x)= 9.765427318782708
# differential_evolution step 96: f(x)= 9.765427318782708
# differential_evolution step 97: f(x)= 9.765427318782708
# differential_evolution step 98: f(x)= 9.765427318782708
# differential_evolution step 99: f(x)= 9.765427318782708
# differential_evolution step 100: f(x)= 9.363645053233942
# differential_evolution step 101: f(x)= 6.966532319581831
# differential_evolution step 102: f(x)= 6.966532319581831
# differential_evolution step 103: f(x)= 6.966532319581831
# differential_evolution step 104: f(x)= 6.966532319581831
# differential_evolution step 105: f(x)= 5.930353162028332
# differential_evolution step 106: f(x)= 5.930353162028332
# differential_evolution step 107: f(x)= 5.930353162028332
# differential_evolution step 108: f(x)= 5.930353162028332
# differential_evolution step 109: f(x)= 5.930353162028332
# differential_evolution step 110: f(x)= 5.930353162028332
# differential_evolution step 111: f(x)= 5.930353162028332
# differential_evolution step 112: f(x)= 5.930353162028332
# differential_evolution step 113: f(x)= 5.930353162028332
# differential_evolution step 114: f(x)= 5.930353162028332
# differential_evolution step 115: f(x)= 5.701309728411929
# differential_evolution step 116: f(x)= 5.701309728411929
# differential_evolution step 117: f(x)= 5.701309728411929
# differential_evolution step 118: f(x)= 5.701309728411929
# differential_evolution step 119: f(x)= 5.701309728411929
# differential_evolution step 120: f(x)= 5.701309728411929
# differential_evolution step 121: f(x)= 5.701309728411929
# differential_evolution step 122: f(x)= 5.701309728411929
# differential_evolution step 123: f(x)= 5.701309728411929
# differential_evolution step 124: f(x)= 5.701309728411929
# differential_evolution step 125: f(x)= 5.701309728411929
# differential_evolution step 126: f(x)= 5.701309728411929
# differential_evolution step 127: f(x)= 5.701309728411929
# differential_evolution step 128: f(x)= 5.701309728411929
# differential_evolution step 129: f(x)= 5.663387776729429
# differential_evolution step 130: f(x)= 5.663387776729429
# differential_evolution step 131: f(x)= 5.663387776729429
# differential_evolution step 132: f(x)= 5.663387776729429
# differential_evolution step 133: f(x)= 5.663387776729429
# differential_evolution step 134: f(x)= 5.663387776729429
# differential_evolution step 135: f(x)= 5.663387776729429
# differential_evolution step 136: f(x)= 5.663387776729429
# differential_evolution step 137: f(x)= 5.583104258757171
# differential_evolution step 138: f(x)= 5.583104258757171
# differential_evolution step 139: f(x)= 5.583104258757171
# differential_evolution step 140: f(x)= 5.583104258757171
# differential_evolution step 141: f(x)= 5.583104258757171
# differential_evolution step 142: f(x)= 5.360442661200004
# differential_evolution step 143: f(x)= 5.360442661200004
# differential_evolution step 144: f(x)= 5.360442661200004
# differential_evolution step 145: f(x)= 5.360442661200004
# differential_evolution step 146: f(x)= 5.2109627258126485
# differential_evolution step 147: f(x)= 5.2109627258126485
# differential_evolution step 148: f(x)= 5.2109627258126485
# differential_evolution step 149: f(x)= 5.2109627258126485
# differential_evolution step 150: f(x)= 5.2109627258126485
# differential_evolution step 151: f(x)= 5.2109627258126485
# differential_evolution step 152: f(x)= 5.2109627258126485
# differential_evolution step 153: f(x)= 5.2109627258126485
# differential_evolution step 154: f(x)= 5.2109627258126485
# differential_evolution step 155: f(x)= 5.2109627258126485
# differential_evolution step 156: f(x)= 5.2109627258126485
# differential_evolution step 157: f(x)= 5.2109627258126485
# differential_evolution step 158: f(x)= 5.032943681330476
# differential_evolution step 159: f(x)= 5.032943681330476
# differential_evolution step 160: f(x)= 5.032943681330476
# differential_evolution step 161: f(x)= 5.032943681330476
# differential_evolution step 162: f(x)= 5.032943681330476
# differential_evolution step 163: f(x)= 5.032943681330476
# differential_evolution step 164: f(x)= 5.032943681330476
# differential_evolution step 165: f(x)= 5.032943681330476
# differential_evolution step 166: f(x)= 5.005957516286269
# differential_evolution step 167: f(x)= 5.005957516286269
# differential_evolution step 168: f(x)= 5.005957516286269
# differential_evolution step 169: f(x)= 5.005957516286269
# differential_evolution step 170: f(x)= 5.005957516286269
# differential_evolution step 171: f(x)= 4.988199721329179
# differential_evolution step 172: f(x)= 4.988199721329179
# differential_evolution step 173: f(x)= 4.988199721329179
# differential_evolution step 174: f(x)= 4.988199721329179
# differential_evolution step 175: f(x)= 4.988199721329179
# differential_evolution step 176: f(x)= 4.988199721329179
# differential_evolution step 177: f(x)= 4.947202632360373
# differential_evolution step 178: f(x)= 4.947202632360373
# differential_evolution step 179: f(x)= 4.947202632360373
# differential_evolution step 180: f(x)= 4.947202632360373
# differential_evolution step 181: f(x)= 4.947202632360373
# differential_evolution step 182: f(x)= 4.945597298356225
# differential_evolution step 183: f(x)= 4.945597298356225
# differential_evolution step 184: f(x)= 4.945597298356225
# differential_evolution step 185: f(x)= 4.945597298356225
# differential_evolution step 186: f(x)= 4.945597298356225
# differential_evolution step 187: f(x)= 4.945597298356225
# differential_evolution step 188: f(x)= 4.848166930261511
# differential_evolution step 189: f(x)= 4.848166930261511
# differential_evolution step 190: f(x)= 4.848166930261511
# differential_evolution step 191: f(x)= 4.848166930261511
# differential_evolution step 192: f(x)= 4.84710949127076
# differential_evolution step 193: f(x)= 4.84710949127076
# differential_evolution step 194: f(x)= 4.824418434281522
# differential_evolution step 195: f(x)= 4.813961322631259
# differential_evolution step 196: f(x)= 4.813961322631259
# differential_evolution step 197: f(x)= 4.813961322631259
# differential_evolution step 198: f(x)= 4.813961322631259
# differential_evolution step 199: f(x)= 4.813961322631259
# differential_evolution step 200: f(x)= 4.813961322631259
# differential_evolution step 201: f(x)= 4.813961322631259
# differential_evolution step 202: f(x)= 4.813961322631259
# differential_evolution step 203: f(x)= 4.813961322631259
# differential_evolution step 204: f(x)= 4.813961322631259
# differential_evolution step 205: f(x)= 4.813961322631259
# differential_evolution step 206: f(x)= 4.813961322631259
# differential_evolution step 207: f(x)= 4.813961322631259
# differential_evolution step 208: f(x)= 4.813961322631259
# differential_evolution step 209: f(x)= 4.769631011263948
# differential_evolution step 210: f(x)= 4.769631011263948
# differential_evolution step 211: f(x)= 4.769631011263948
# differential_evolution step 212: f(x)= 4.769631011263948
# differential_evolution step 213: f(x)= 4.769631011263948
# differential_evolution step 214: f(x)= 4.769631011263948
# differential_evolution step 215: f(x)= 4.769631011263948
# differential_evolution step 216: f(x)= 4.769631011263948
# differential_evolution step 217: f(x)= 4.769631011263948
# differential_evolution step 218: f(x)= 4.769631011263948
# differential_evolution step 219: f(x)= 4.769631011263948
# differential_evolution step 220: f(x)= 4.765353809268738
# differential_evolution step 221: f(x)= 4.765353809268738
# differential_evolution step 222: f(x)= 4.765353809268738
# differential_evolution step 223: f(x)= 4.765353809268738
# differential_evolution step 224: f(x)= 4.765353809268738
# differential_evolution step 225: f(x)= 4.765353809268738
# differential_evolution step 226: f(x)= 4.765353809268738
# differential_evolution step 227: f(x)= 4.765353809268738
# differential_evolution step 228: f(x)= 4.676470292018414
# differential_evolution step 229: f(x)= 4.676470292018414
# differential_evolution step 230: f(x)= 4.676470292018414
# differential_evolution step 231: f(x)= 4.676470292018414
# differential_evolution step 232: f(x)= 4.676470292018414
# differential_evolution step 233: f(x)= 4.676470292018414
# differential_evolution step 234: f(x)= 4.676470292018414
# differential_evolution step 235: f(x)= 4.676470292018414
# differential_evolution step 236: f(x)= 4.634510450165612
# differential_evolution step 237: f(x)= 4.634510450165612
# differential_evolution step 238: f(x)= 4.634510450165612
# differential_evolution step 239: f(x)= 4.634510450165612
# differential_evolution step 240: f(x)= 4.634510450165612
# differential_evolution step 241: f(x)= 4.634510450165612
# differential_evolution step 242: f(x)= 4.634510450165612
# differential_evolution step 243: f(x)= 4.634510450165612
# differential_evolution step 244: f(x)= 4.634510450165612
# differential_evolution step 245: f(x)= 4.634510450165612
# differential_evolution step 246: f(x)= 4.634510450165612
# differential_evolution step 247: f(x)= 4.634510450165612
# differential_evolution step 248: f(x)= 4.634510450165612
# differential_evolution step 249: f(x)= 4.634510450165612
# differential_evolution step 250: f(x)= 4.634510450165612
# differential_evolution step 251: f(x)= 4.602913805069758
# differential_evolution step 252: f(x)= 4.557682264938074
# differential_evolution step 253: f(x)= 4.557682264938074
# differential_evolution step 254: f(x)= 4.557682264938074
# differential_evolution step 255: f(x)= 4.557682264938074
# differential_evolution step 256: f(x)= 4.557682264938074
# differential_evolution step 257: f(x)= 4.55722224058585
# differential_evolution step 258: f(x)= 4.55722224058585
# differential_evolution step 259: f(x)= 4.55722224058585
# differential_evolution step 260: f(x)= 4.55722224058585
# differential_evolution step 261: f(x)= 4.55722224058585
# differential_evolution step 262: f(x)= 4.55722224058585
# differential_evolution step 263: f(x)= 4.55722224058585
# differential_evolution step 264: f(x)= 4.55722224058585
# differential_evolution step 265: f(x)= 4.55722224058585
# differential_evolution step 266: f(x)= 4.55722224058585
# differential_evolution step 267: f(x)= 4.55722224058585
# differential_evolution step 268: f(x)= 4.512047164106062
# differential_evolution step 269: f(x)= 4.512047164106062
# differential_evolution step 270: f(x)= 4.512047164106062
# differential_evolution step 271: f(x)= 4.512047164106062
# differential_evolution step 272: f(x)= 4.506128496471885
# differential_evolution step 273: f(x)= 4.506128496471885
# differential_evolution step 274: f(x)= 4.506128496471885
# differential_evolution step 275: f(x)= 4.506128496471885
# differential_evolution step 276: f(x)= 4.506128496471885
# differential_evolution step 277: f(x)= 4.506128496471885
# differential_evolution step 278: f(x)= 4.506128496471885
# differential_evolution step 279: f(x)= 4.4996080412861925
# differential_evolution step 280: f(x)= 4.4996080412861925
# differential_evolution step 281: f(x)= 4.4996080412861925
# differential_evolution step 282: f(x)= 4.4996080412861925
# differential_evolution step 283: f(x)= 4.4996080412861925
# differential_evolution step 284: f(x)= 4.4996080412861925
# differential_evolution step 285: f(x)= 4.4996080412861925
# differential_evolution step 286: f(x)= 4.4996080412861925
# differential_evolution step 287: f(x)= 4.4996080412861925
# differential_evolution step 288: f(x)= 4.4996080412861925
# differential_evolution step 289: f(x)= 4.479779795299242
# differential_evolution step 290: f(x)= 4.479779795299242
# differential_evolution step 291: f(x)= 4.465431958504257
# differential_evolution step 292: f(x)= 4.465431958504257
# differential_evolution step 293: f(x)= 4.465431958504257
# differential_evolution step 294: f(x)= 4.465431958504257
# differential_evolution step 295: f(x)= 4.465431958504257
# differential_evolution step 296: f(x)= 4.465431958504257
# differential_evolution step 297: f(x)= 4.465431958504257
# differential_evolution step 298: f(x)= 4.465431958504257
# differential_evolution step 299: f(x)= 4.465431958504257
# differential_evolution step 300: f(x)= 4.465431958504257
# differential_evolution step 301: f(x)= 4.465431958504257
# differential_evolution step 302: f(x)= 4.465431958504257
# differential_evolution step 303: f(x)= 4.465431958504257
# differential_evolution step 304: f(x)= 4.465431958504257
# differential_evolution step 305: f(x)= 4.465431958504257
# differential_evolution step 306: f(x)= 4.465431958504257
# differential_evolution step 307: f(x)= 4.465431958504257
# differential_evolution step 308: f(x)= 4.465431958504257
# differential_evolution step 309: f(x)= 4.465431958504257
# differential_evolution step 310: f(x)= 4.465431958504257
# differential_evolution step 311: f(x)= 4.465431958504257
# differential_evolution step 312: f(x)= 4.465431958504257
# differential_evolution step 313: f(x)= 4.432551884043195
# differential_evolution step 314: f(x)= 4.432551884043195
# differential_evolution step 315: f(x)= 4.432551884043195
# differential_evolution step 316: f(x)= 4.432551884043195
# differential_evolution step 317: f(x)= 4.432551884043195
# differential_evolution step 318: f(x)= 4.432551884043195
# differential_evolution step 319: f(x)= 4.421818518370191
# differential_evolution step 320: f(x)= 4.421818518370191
# differential_evolution step 321: f(x)= 4.421818518370191
# differential_evolution step 322: f(x)= 4.418058654487115
# differential_evolution step 323: f(x)= 4.398177636094452
# differential_evolution step 324: f(x)= 4.398177636094452
# differential_evolution step 325: f(x)= 4.3844512528356745
# differential_evolution step 326: f(x)= 4.3844512528356745
# differential_evolution step 327: f(x)= 4.3844512528356745
# differential_evolution step 328: f(x)= 4.370073222379996
# differential_evolution step 329: f(x)= 4.370073222379996
# differential_evolution step 330: f(x)= 4.368711884057194
# differential_evolution step 331: f(x)= 4.351269388255261
# differential_evolution step 332: f(x)= 4.351269388255261
# differential_evolution step 333: f(x)= 4.351269388255261
# differential_evolution step 334: f(x)= 4.351269388255261
# differential_evolution step 335: f(x)= 4.351269388255261
# differential_evolution step 336: f(x)= 4.351269388255261
# differential_evolution step 337: f(x)= 4.351269388255261
# differential_evolution step 338: f(x)= 4.351269388255261
# differential_evolution step 339: f(x)= 4.351269388255261
# differential_evolution step 340: f(x)= 4.351269388255261
# differential_evolution step 341: f(x)= 4.351269388255261
# differential_evolution step 342: f(x)= 4.338166483643246
# differential_evolution step 343: f(x)= 4.3149311293967045
# differential_evolution step 344: f(x)= 4.3149311293967045
# differential_evolution step 345: f(x)= 4.297434156403871
# differential_evolution step 346: f(x)= 4.283370573384549
# differential_evolution step 347: f(x)= 4.283370573384549
# differential_evolution step 348: f(x)= 4.243626208702236
# differential_evolution step 349: f(x)= 4.243626208702236
# differential_evolution step 350: f(x)= 4.243626208702236
# differential_evolution step 351: f(x)= 4.243626208702236
# differential_evolution step 352: f(x)= 4.243626208702236
# differential_evolution step 353: f(x)= 4.243626208702236
# differential_evolution step 354: f(x)= 4.243626208702236
# differential_evolution step 355: f(x)= 4.243626208702236
# differential_evolution step 356: f(x)= 4.243626208702236
# differential_evolution step 357: f(x)= 4.243626208702236
# differential_evolution step 358: f(x)= 4.243626208702236
# differential_evolution step 359: f(x)= 4.243626208702236
# differential_evolution step 360: f(x)= 4.243626208702236
# differential_evolution step 361: f(x)= 4.243626208702236
# differential_evolution step 362: f(x)= 4.243626208702236
# differential_evolution step 363: f(x)= 4.243626208702236
# differential_evolution step 364: f(x)= 4.243626208702236
# differential_evolution step 365: f(x)= 4.243626208702236
# differential_evolution step 366: f(x)= 4.217938892525951
# differential_evolution step 367: f(x)= 4.217938892525951
# differential_evolution step 368: f(x)= 4.217938892525951
# differential_evolution step 369: f(x)= 4.217938892525951
# differential_evolution step 370: f(x)= 4.217938892525951
# differential_evolution step 371: f(x)= 4.1808968980674805
# differential_evolution step 372: f(x)= 4.174293752943081
# differential_evolution step 373: f(x)= 4.174293752943081
# differential_evolution step 374: f(x)= 4.174293752943081
# differential_evolution step 375: f(x)= 4.174293752943081
# differential_evolution step 376: f(x)= 4.174293752943081
# differential_evolution step 377: f(x)= 4.174293752943081
# differential_evolution step 378: f(x)= 4.174293752943081
# differential_evolution step 379: f(x)= 4.163443743278398
# differential_evolution step 380: f(x)= 4.163443743278398
# differential_evolution step 381: f(x)= 4.163443743278398
# differential_evolution step 382: f(x)= 4.163443743278398
# differential_evolution step 383: f(x)= 4.127083931253631
# differential_evolution step 384: f(x)= 4.127083931253631
# differential_evolution step 385: f(x)= 4.127083931253631
# differential_evolution step 386: f(x)= 4.111946183508087
# differential_evolution step 387: f(x)= 4.111946183508087
# differential_evolution step 388: f(x)= 4.111946183508087
# differential_evolution step 389: f(x)= 4.111946183508087
# differential_evolution step 390: f(x)= 4.106063045234008
# differential_evolution step 391: f(x)= 4.101226014720678
# differential_evolution step 392: f(x)= 4.07111903239869
# differential_evolution step 393: f(x)= 4.040351831193184
# differential_evolution step 394: f(x)= 4.01137626785519
# differential_evolution step 395: f(x)= 4.01137626785519
# differential_evolution step 396: f(x)= 3.993183148155359
# differential_evolution step 397: f(x)= 3.993183148155359
# differential_evolution step 398: f(x)= 3.993183148155359
# differential_evolution step 399: f(x)= 3.993183148155359
# differential_evolution step 400: f(x)= 3.993183148155359
# differential_evolution step 401: f(x)= 3.993183148155359
# differential_evolution step 402: f(x)= 3.993183148155359
# differential_evolution step 403: f(x)= 3.993183148155359
# differential_evolution step 404: f(x)= 3.9885265226730877
# differential_evolution step 405: f(x)= 3.9885265226730877
# differential_evolution step 406: f(x)= 3.9783311675299866
# differential_evolution step 407: f(x)= 3.9783311675299866
# differential_evolution step 408: f(x)= 3.9783311675299866
# differential_evolution step 409: f(x)= 3.9783311675299866
# differential_evolution step 410: f(x)= 3.9783311675299866
# differential_evolution step 411: f(x)= 3.9783311675299866
# differential_evolution step 412: f(x)= 3.933568886423162
# differential_evolution step 413: f(x)= 3.933568886423162
# differential_evolution step 414: f(x)= 3.933568886423162
# differential_evolution step 415: f(x)= 3.914064516654376
# differential_evolution step 416: f(x)= 3.914064516654376
# differential_evolution step 417: f(x)= 3.9124346651986213
# differential_evolution step 418: f(x)= 3.9124346651986213
# differential_evolution step 419: f(x)= 3.9124346651986213
# differential_evolution step 420: f(x)= 3.9124346651986213
# differential_evolution step 421: f(x)= 3.9124346651986213
# differential_evolution step 422: f(x)= 3.8735671967348817
# differential_evolution step 423: f(x)= 3.8735671967348817
# differential_evolution step 424: f(x)= 3.8735671967348817
# differential_evolution step 425: f(x)= 3.8735671967348817
# differential_evolution step 426: f(x)= 3.8735671967348817
# differential_evolution step 427: f(x)= 3.8735671967348817
# differential_evolution step 428: f(x)= 3.8735671967348817
# differential_evolution step 429: f(x)= 3.8735671967348817
# differential_evolution step 430: f(x)= 3.8735671967348817
# differential_evolution step 431: f(x)= 3.866004519487617
# differential_evolution step 432: f(x)= 3.866004519487617
# differential_evolution step 433: f(x)= 3.866004519487617
# differential_evolution step 434: f(x)= 3.866004519487617
# differential_evolution step 435: f(x)= 3.8542386493179692
# differential_evolution step 436: f(x)= 3.8542386493179692
# differential_evolution step 437: f(x)= 3.8542386493179692
# differential_evolution step 438: f(x)= 3.8542386493179692
# differential_evolution step 439: f(x)= 3.836367800558825
# differential_evolution step 440: f(x)= 3.832326768131596
# differential_evolution step 441: f(x)= 3.832326768131596
# differential_evolution step 442: f(x)= 3.7879466251948775
# differential_evolution step 443: f(x)= 3.7879466251948775
# differential_evolution step 444: f(x)= 3.7879466251948775
# differential_evolution step 445: f(x)= 3.7879466251948775
# differential_evolution step 446: f(x)= 3.7879466251948775
# differential_evolution step 447: f(x)= 3.7879466251948775
# differential_evolution step 448: f(x)= 3.7845253029323924
# differential_evolution step 449: f(x)= 3.7845253029323924
# differential_evolution step 450: f(x)= 3.7819208155985717
# differential_evolution step 451: f(x)= 3.7819208155985717
# differential_evolution step 452: f(x)= 3.7819208155985717
# differential_evolution step 453: f(x)= 3.7819208155985717
# differential_evolution step 454: f(x)= 3.7819208155985717
# differential_evolution step 455: f(x)= 3.7819208155985717
# differential_evolution step 456: f(x)= 3.767575452705475
# differential_evolution step 457: f(x)= 3.767575452705475
# differential_evolution step 458: f(x)= 3.767575452705475
# differential_evolution step 459: f(x)= 3.7613017860765776
# differential_evolution step 460: f(x)= 3.7613017860765776
# differential_evolution step 461: f(x)= 3.7613017860765776
# differential_evolution step 462: f(x)= 3.7613017860765776
# differential_evolution step 463: f(x)= 3.7613017860765776
# differential_evolution step 464: f(x)= 3.7613017860765776
# differential_evolution step 465: f(x)= 3.7613017860765776
# differential_evolution step 466: f(x)= 3.7613017860765776
# differential_evolution step 467: f(x)= 3.7613017860765776
# differential_evolution step 468: f(x)= 3.7613017860765776
# differential_evolution step 469: f(x)= 3.7613017860765776
# differential_evolution step 470: f(x)= 3.757691400572873
# differential_evolution step 471: f(x)= 3.724341663913697
# differential_evolution step 472: f(x)= 3.724341663913697
# differential_evolution step 473: f(x)= 3.724341663913697
# differential_evolution step 474: f(x)= 3.724341663913697
# differential_evolution step 475: f(x)= 3.724341663913697
# differential_evolution step 476: f(x)= 3.724341663913697
# differential_evolution step 477: f(x)= 3.724341663913697
# differential_evolution step 478: f(x)= 3.724341663913697
# differential_evolution step 479: f(x)= 3.724341663913697
# differential_evolution step 480: f(x)= 3.724341663913697
# differential_evolution step 481: f(x)= 3.7213014764377443
# differential_evolution step 482: f(x)= 3.7213014764377443
# differential_evolution step 483: f(x)= 3.7213014764377443
# differential_evolution step 484: f(x)= 3.7213014764377443
# differential_evolution step 485: f(x)= 3.7213014764377443
# differential_evolution step 486: f(x)= 3.7213014764377443
# differential_evolution step 487: f(x)= 3.7213014764377443
# differential_evolution step 488: f(x)= 3.7213014764377443
# differential_evolution step 489: f(x)= 3.6974878053814635
# differential_evolution step 490: f(x)= 3.6974878053814635
# differential_evolution step 491: f(x)= 3.6974878053814635
# differential_evolution step 492: f(x)= 3.6797883789144565
# differential_evolution step 493: f(x)= 3.6797883789144565
# differential_evolution step 494: f(x)= 3.6797883789144565
# differential_evolution step 495: f(x)= 3.6797883789144565
# differential_evolution step 496: f(x)= 3.6625594667115076
# differential_evolution step 497: f(x)= 3.6625594667115076
# differential_evolution step 498: f(x)= 3.6625594667115076
# differential_evolution step 499: f(x)= 3.6625594667115076
# differential_evolution step 500: f(x)= 3.6625594667115076
# differential_evolution step 501: f(x)= 3.6625594667115076
# differential_evolution step 502: f(x)= 3.6625594667115076
# differential_evolution step 503: f(x)= 3.6625594667115076
# differential_evolution step 504: f(x)= 3.6625594667115076
# differential_evolution step 505: f(x)= 3.6625594667115076
# differential_evolution step 506: f(x)= 3.6625594667115076
# differential_evolution step 507: f(x)= 3.65680029889671
# differential_evolution step 508: f(x)= 3.65680029889671
# differential_evolution step 509: f(x)= 3.65680029889671
# differential_evolution step 510: f(x)= 3.65680029889671
# differential_evolution step 511: f(x)= 3.65680029889671
# differential_evolution step 512: f(x)= 3.6567173013312253
# differential_evolution step 513: f(x)= 3.6567173013312253
# differential_evolution step 514: f(x)= 3.6481520533511893
# differential_evolution step 515: f(x)= 3.6481520533511893
# differential_evolution step 516: f(x)= 3.6481520533511893
# differential_evolution step 517: f(x)= 3.6369226502047485
# differential_evolution step 518: f(x)= 3.6369226502047485
# differential_evolution step 519: f(x)= 3.6341662696125967
# differential_evolution step 520: f(x)= 3.6341662696125967
# differential_evolution step 521: f(x)= 3.6273288281164517
# differential_evolution step 522: f(x)= 3.6273288281164517
# differential_evolution step 523: f(x)= 3.6273288281164517
# differential_evolution step 524: f(x)= 3.6273288281164517
# differential_evolution step 525: f(x)= 3.626053855630697
# differential_evolution step 526: f(x)= 3.626053855630697
# differential_evolution step 527: f(x)= 3.626053855630697
# differential_evolution step 528: f(x)= 3.62529092462602
# differential_evolution step 529: f(x)= 3.62529092462602
# differential_evolution step 530: f(x)= 3.62529092462602
# differential_evolution step 531: f(x)= 3.6188413960440817
# differential_evolution step 532: f(x)= 3.6165311606864132
# differential_evolution step 533: f(x)= 3.6165311606864132
# differential_evolution step 534: f(x)= 3.6165311606864132
# differential_evolution step 535: f(x)= 3.6165311606864132
# differential_evolution step 536: f(x)= 3.6165311606864132
# differential_evolution step 537: f(x)= 3.6165311606864132
# differential_evolution step 538: f(x)= 3.6165311606864132
# differential_evolution step 539: f(x)= 3.6165311606864132
# differential_evolution step 540: f(x)= 3.6165311606864132
# differential_evolution step 541: f(x)= 3.6037647759523836
# differential_evolution step 542: f(x)= 3.6037647759523836
# differential_evolution step 543: f(x)= 3.6037647759523836
# differential_evolution step 544: f(x)= 3.6037647759523836
# differential_evolution step 545: f(x)= 3.6037647759523836
# differential_evolution step 546: f(x)= 3.588890617633642
# differential_evolution step 547: f(x)= 3.588890617633642
# differential_evolution step 548: f(x)= 3.588890617633642
# differential_evolution step 549: f(x)= 3.588890617633642
# differential_evolution step 550: f(x)= 3.588890617633642
# differential_evolution step 551: f(x)= 3.5882829730335706
# differential_evolution step 552: f(x)= 3.5806917474634465
# differential_evolution step 553: f(x)= 3.5806917474634465
# differential_evolution step 554: f(x)= 3.5806917474634465
# differential_evolution step 555: f(x)= 3.5806917474634465
# differential_evolution step 556: f(x)= 3.5806917474634465
# differential_evolution step 557: f(x)= 3.5761063472267853
# differential_evolution step 558: f(x)= 3.5761063472267853
# differential_evolution step 559: f(x)= 3.5761063472267853
# differential_evolution step 560: f(x)= 3.5761063472267853
# differential_evolution step 561: f(x)= 3.5761063472267853
# differential_evolution step 562: f(x)= 3.5761063472267853
# differential_evolution step 563: f(x)= 3.5761063472267853
# differential_evolution step 564: f(x)= 3.5761063472267853
# differential_evolution step 565: f(x)= 3.5761063472267853
# differential_evolution step 566: f(x)= 3.5761063472267853
# differential_evolution step 567: f(x)= 3.571078973322944
# differential_evolution step 568: f(x)= 3.571078973322944
# differential_evolution step 569: f(x)= 3.571078973322944
# differential_evolution step 570: f(x)= 3.571078973322944
# differential_evolution step 571: f(x)= 3.571078973322944
# differential_evolution step 572: f(x)= 3.571078973322944
# differential_evolution step 573: f(x)= 3.571078973322944
# differential_evolution step 574: f(x)= 3.571078973322944
# differential_evolution step 575: f(x)= 3.571078973322944
# differential_evolution step 576: f(x)= 3.571078973322944
# differential_evolution step 577: f(x)= 3.571078973322944
# differential_evolution step 578: f(x)= 3.571078973322944
# differential_evolution step 579: f(x)= 3.568619435378886
# differential_evolution step 580: f(x)= 3.568619435378886
# differential_evolution step 581: f(x)= 3.568619435378886
# differential_evolution step 582: f(x)= 3.568619435378886
# differential_evolution step 583: f(x)= 3.568619435378886
# differential_evolution step 584: f(x)= 3.568619435378886
# differential_evolution step 585: f(x)= 3.5676674561445645
# differential_evolution step 586: f(x)= 3.5676674561445645
# differential_evolution step 587: f(x)= 3.5676674561445645
# differential_evolution step 588: f(x)= 3.5676674561445645
# differential_evolution step 589: f(x)= 3.5676674561445645
# differential_evolution step 590: f(x)= 3.5676674561445645
# differential_evolution step 591: f(x)= 3.5676674561445645
# differential_evolution step 592: f(x)= 3.5637764644078556
# differential_evolution step 593: f(x)= 3.5637764644078556
# differential_evolution step 594: f(x)= 3.5637764644078556
# differential_evolution step 595: f(x)= 3.5637764644078556
# differential_evolution step 596: f(x)= 3.5637764644078556
# differential_evolution step 597: f(x)= 3.5637764644078556
# differential_evolution step 598: f(x)= 3.5637764644078556
# differential_evolution step 599: f(x)= 3.5631127969659073
# differential_evolution step 600: f(x)= 3.5631127969659073
# differential_evolution step 601: f(x)= 3.5631127969659073
# differential_evolution step 602: f(x)= 3.5631127969659073
# differential_evolution step 603: f(x)= 3.5631127969659073
# differential_evolution step 604: f(x)= 3.5631127969659073
# differential_evolution step 605: f(x)= 3.5631127969659073
# differential_evolution step 606: f(x)= 3.5631127969659073
# differential_evolution step 607: f(x)= 3.5631127969659073
# differential_evolution step 608: f(x)= 3.5631127969659073
# differential_evolution step 609: f(x)= 3.5631127969659073
# differential_evolution step 610: f(x)= 3.5631127969659073
# differential_evolution step 611: f(x)= 3.5631127969659073
# differential_evolution step 612: f(x)= 3.5631127969659073
# differential_evolution step 613: f(x)= 3.5631127969659073
# differential_evolution step 614: f(x)= 3.5631127969659073
# differential_evolution step 615: f(x)= 3.5631127969659073
# differential_evolution step 616: f(x)= 3.5631127969659073
# differential_evolution step 617: f(x)= 3.5631127969659073
# differential_evolution step 618: f(x)= 3.5631127969659073
# differential_evolution step 619: f(x)= 3.562548118635079
# differential_evolution step 620: f(x)= 3.562548118635079
# differential_evolution step 621: f(x)= 3.562548118635079
# differential_evolution step 622: f(x)= 3.562548118635079
# differential_evolution step 623: f(x)= 3.5612928523142298
# differential_evolution step 624: f(x)= 3.5612928523142298
# differential_evolution step 625: f(x)= 3.5612928523142298
# differential_evolution step 626: f(x)= 3.5612928523142298
# differential_evolution step 627: f(x)= 3.5612928523142298
# differential_evolution step 628: f(x)= 3.5612928523142298
# differential_evolution step 629: f(x)= 3.5612928523142298
# differential_evolution step 630: f(x)= 3.5612928523142298
# differential_evolution step 631: f(x)= 3.5612928523142298
# differential_evolution step 632: f(x)= 3.5612928523142298
# differential_evolution step 633: f(x)= 3.5606758460385346
# differential_evolution step 634: f(x)= 3.5606758460385346
# differential_evolution step 635: f(x)= 3.5606758460385346
# differential_evolution step 636: f(x)= 3.5606758460385346
# differential_evolution step 637: f(x)= 3.5606758460385346
# differential_evolution step 638: f(x)= 3.5606758460385346
# differential_evolution step 639: f(x)= 3.560076102266927
# differential_evolution step 640: f(x)= 3.560076102266927
# differential_evolution step 641: f(x)= 3.5595179109883652
# differential_evolution step 642: f(x)= 3.5595179109883652
# differential_evolution step 643: f(x)= 3.5595179109883652
# differential_evolution step 644: f(x)= 3.5595179109883652
# differential_evolution step 645: f(x)= 3.5595179109883652
# differential_evolution step 646: f(x)= 3.5595179109883652
# differential_evolution step 647: f(x)= 3.5595179109883652
# differential_evolution step 648: f(x)= 3.5595179109883652
# differential_evolution step 649: f(x)= 3.559137518912945
# differential_evolution step 650: f(x)= 3.559137518912945
# differential_evolution step 651: f(x)= 3.559137518912945
# differential_evolution step 652: f(x)= 3.559015620832717
# differential_evolution step 653: f(x)= 3.559015620832717
# differential_evolution step 654: f(x)= 3.5588428264865324
# differential_evolution step 655: f(x)= 3.5588428264865324
# differential_evolution step 656: f(x)= 3.5588428264865324
# differential_evolution step 657: f(x)= 3.5588428264865324
# differential_evolution step 658: f(x)= 3.5588428264865324
# differential_evolution step 659: f(x)= 3.5588428264865324
# differential_evolution step 660: f(x)= 3.5588428264865324
# differential_evolution step 661: f(x)= 3.5588428264865324
# differential_evolution step 662: f(x)= 3.5582630062112575
# differential_evolution step 663: f(x)= 3.5582630062112575
# differential_evolution step 664: f(x)= 3.5582630062112575
# differential_evolution step 665: f(x)= 3.5582630062112575
# differential_evolution step 666: f(x)= 3.5582630062112575
# differential_evolution step 667: f(x)= 3.5582630062112575
# differential_evolution step 668: f(x)= 3.5582630062112575
# differential_evolution step 669: f(x)= 3.5582630062112575
# differential_evolution step 670: f(x)= 3.5582630062112575
# differential_evolution step 671: f(x)= 3.5582630062112575
# differential_evolution step 672: f(x)= 3.5582630062112575
# differential_evolution step 673: f(x)= 3.5582630062112575
# differential_evolution step 674: f(x)= 3.5579137671401666
# differential_evolution step 675: f(x)= 3.5579137671401666
# differential_evolution step 676: f(x)= 3.5579137671401666
# differential_evolution step 677: f(x)= 3.5579137671401666
# differential_evolution step 678: f(x)= 3.5579137671401666
# differential_evolution step 679: f(x)= 3.5579137671401666
# differential_evolution step 680: f(x)= 3.5579137671401666
# differential_evolution step 681: f(x)= 3.5579137671401666
# differential_evolution step 682: f(x)= 3.5579137671401666
# differential_evolution step 683: f(x)= 3.5579137671401666
# differential_evolution step 684: f(x)= 3.5579137671401666
# differential_evolution step 685: f(x)= 3.5579137671401666
# differential_evolution step 686: f(x)= 3.557570464603205
# differential_evolution step 687: f(x)= 3.557570464603205
# differential_evolution step 688: f(x)= 3.557570464603205
# differential_evolution step 689: f(x)= 3.557570464603205
# differential_evolution step 690: f(x)= 3.5575397892087857
# differential_evolution step 691: f(x)= 3.5575397892087857
# differential_evolution step 692: f(x)= 3.5575397892087857
# differential_evolution step 693: f(x)= 3.5575397892087857
# differential_evolution step 694: f(x)= 3.557285022111903
# differential_evolution step 695: f(x)= 3.557285022111903
# differential_evolution step 696: f(x)= 3.557216626646207
# differential_evolution step 697: f(x)= 3.557216626646207
# differential_evolution step 698: f(x)= 3.557216626646207
# differential_evolution step 699: f(x)= 3.557216626646207
# differential_evolution step 700: f(x)= 3.557216626646207
# differential_evolution step 701: f(x)= 3.557216626646207
# differential_evolution step 702: f(x)= 3.557216626646207
# differential_evolution step 703: f(x)= 3.557216626646207
# differential_evolution step 704: f(x)= 3.557216626646207
# differential_evolution step 705: f(x)= 3.557216626646207
# differential_evolution step 706: f(x)= 3.557216626646207
# differential_evolution step 707: f(x)= 3.557216626646207
# differential_evolution step 708: f(x)= 3.557216626646207
# differential_evolution step 709: f(x)= 3.557216626646207
# differential_evolution step 710: f(x)= 3.557216626646207
# differential_evolution step 711: f(x)= 3.557216626646207
# differential_evolution step 712: f(x)= 3.557216626646207
# differential_evolution step 713: f(x)= 3.5571684551141436
# differential_evolution step 714: f(x)= 3.5571684551141436
# differential_evolution step 715: f(x)= 3.5571684551141436
# differential_evolution step 716: f(x)= 3.5571684551141436
# differential_evolution step 717: f(x)= 3.557168411363245
# differential_evolution step 718: f(x)= 3.557168411363245
# differential_evolution step 719: f(x)= 3.557168411363245
# differential_evolution step 720: f(x)= 3.557168411363245
# differential_evolution step 721: f(x)= 3.5571169164991225
# differential_evolution step 722: f(x)= 3.5571169164991225
# differential_evolution step 723: f(x)= 3.5571169164991225
# differential_evolution step 724: f(x)= 3.5571169164991225
# differential_evolution step 725: f(x)= 3.5566839070737615
# differential_evolution step 726: f(x)= 3.5566839070737615
# differential_evolution step 727: f(x)= 3.5566839070737615
# differential_evolution step 728: f(x)= 3.5566839070737615
# differential_evolution step 729: f(x)= 3.5566839070737615
# differential_evolution step 730: f(x)= 3.5566839070737615
# differential_evolution step 731: f(x)= 3.5566839070737615
# differential_evolution step 732: f(x)= 3.5566839070737615
# differential_evolution step 733: f(x)= 3.5566839070737615
# differential_evolution step 734: f(x)= 3.5566839070737615
# differential_evolution step 735: f(x)= 3.5566839070737615
# differential_evolution step 736: f(x)= 3.5566839070737615
# differential_evolution step 737: f(x)= 3.5566839070737615
# differential_evolution step 738: f(x)= 3.5566839070737615
# differential_evolution step 739: f(x)= 3.5566839070737615
# differential_evolution step 740: f(x)= 3.5566839070737615
# differential_evolution step 741: f(x)= 3.5566839070737615
# differential_evolution step 742: f(x)= 3.5566839070737615
# differential_evolution step 743: f(x)= 3.5566839070737615
# differential_evolution step 744: f(x)= 3.5566839070737615
# differential_evolution step 745: f(x)= 3.5566839070737615
# differential_evolution step 746: f(x)= 3.5566839070737615
# differential_evolution step 747: f(x)= 3.5566839070737615
# differential_evolution step 748: f(x)= 3.5566839070737615
# differential_evolution step 749: f(x)= 3.5566839070737615
# differential_evolution step 750: f(x)= 3.5566839070737615
# differential_evolution step 751: f(x)= 3.5566839070737615
# differential_evolution step 752: f(x)= 3.5566839070737615
# differential_evolution step 753: f(x)= 3.5566839070737615
# differential_evolution step 754: f(x)= 3.5566839070737615
# differential_evolution step 755: f(x)= 3.5566839070737615
# differential_evolution step 756: f(x)= 3.5566839070737615
# differential_evolution step 757: f(x)= 3.5566839070737615
# differential_evolution step 758: f(x)= 3.5566839070737615
# differential_evolution step 759: f(x)= 3.5566839070737615
# differential_evolution step 760: f(x)= 3.556681379539725
# differential_evolution step 761: f(x)= 3.556681379539725
# differential_evolution step 762: f(x)= 3.556681379539725
# differential_evolution step 763: f(x)= 3.556681379539725
# differential_evolution step 764: f(x)= 3.556681379539725
# differential_evolution step 765: f(x)= 3.556681379539725
# differential_evolution step 766: f(x)= 3.556681379539725
# differential_evolution step 767: f(x)= 3.556681379539725
# differential_evolution step 768: f(x)= 3.556681379539725
# differential_evolution step 769: f(x)= 3.556681379539725
# differential_evolution step 770: f(x)= 3.556681379539725
# differential_evolution step 771: f(x)= 3.556681379539725
# differential_evolution step 772: f(x)= 3.556681379539725
# differential_evolution step 773: f(x)= 3.556680030126041
# differential_evolution step 774: f(x)= 3.556680030126041
# differential_evolution step 775: f(x)= 3.556680030126041
# differential_evolution step 776: f(x)= 3.556680030126041
# differential_evolution step 777: f(x)= 3.556616800461114
# differential_evolution step 778: f(x)= 3.556616800461114
# differential_evolution step 779: f(x)= 3.556616800461114
# differential_evolution step 780: f(x)= 3.556616800461114
# differential_evolution step 781: f(x)= 3.556616800461114
# differential_evolution step 782: f(x)= 3.556616800461114
# differential_evolution step 783: f(x)= 3.5565885155932055
# differential_evolution step 784: f(x)= 3.5565885155932055
# differential_evolution step 785: f(x)= 3.5565885155932055
# differential_evolution step 786: f(x)= 3.556581135482557
# differential_evolution step 787: f(x)= 3.556581135482557
# differential_evolution step 788: f(x)= 3.556581135482557
# differential_evolution step 789: f(x)= 3.556581135482557
# differential_evolution step 790: f(x)= 3.556581135482557
# differential_evolution step 791: f(x)= 3.556581135482557
# differential_evolution step 792: f(x)= 3.556581135482557
# differential_evolution step 793: f(x)= 3.556581135482557
# differential_evolution step 794: f(x)= 3.5565728894980873
# differential_evolution step 795: f(x)= 3.5565728894980873
# differential_evolution step 796: f(x)= 3.5565728894980873
# differential_evolution step 797: f(x)= 3.5565728894980873
# differential_evolution step 798: f(x)= 3.5565728894980873
# differential_evolution step 799: f(x)= 3.5565728894980873
# differential_evolution step 800: f(x)= 3.5565728894980873
# differential_evolution step 801: f(x)= 3.5565728894980873
# differential_evolution step 802: f(x)= 3.5565728894980873
# differential_evolution step 803: f(x)= 3.5565728894980873
# differential_evolution step 804: f(x)= 3.5565728894980873
# differential_evolution step 805: f(x)= 3.556570392879283
# differential_evolution step 806: f(x)= 3.556570392879283
# differential_evolution step 807: f(x)= 3.556570392879283
# differential_evolution step 808: f(x)= 3.556537800547341
# differential_evolution step 809: f(x)= 3.556537800547341
# differential_evolution step 810: f(x)= 3.556537800547341
# differential_evolution step 811: f(x)= 3.556537800547341
# differential_evolution step 812: f(x)= 3.556537800547341
# differential_evolution step 813: f(x)= 3.556537800547341
# differential_evolution step 814: f(x)= 3.556537800547341
# differential_evolution step 815: f(x)= 3.556537800547341
# differential_evolution step 816: f(x)= 3.556537800547341
# differential_evolution step 817: f(x)= 3.556537800547341
# differential_evolution step 818: f(x)= 3.556537800547341
# differential_evolution step 819: f(x)= 3.556537800547341
# differential_evolution step 820: f(x)= 3.556537800547341
# differential_evolution step 821: f(x)= 3.556537800547341
# differential_evolution step 822: f(x)= 3.556537800547341
# differential_evolution step 823: f(x)= 3.556537800547341
# differential_evolution step 824: f(x)= 3.556537800547341
# differential_evolution step 825: f(x)= 3.556537800547341
# differential_evolution step 826: f(x)= 3.556537800547341
# differential_evolution step 827: f(x)= 3.556537800547341
# differential_evolution step 828: f(x)= 3.556537800547341
# differential_evolution step 829: f(x)= 3.556537800547341
# differential_evolution step 830: f(x)= 3.5565334404725757
# differential_evolution step 831: f(x)= 3.556532678145222
# differential_evolution step 832: f(x)= 3.5565291084829824
# differential_evolution step 833: f(x)= 3.5565291084829824
# differential_evolution step 834: f(x)= 3.556528123619122
# differential_evolution step 835: f(x)= 3.556528123619122
# differential_evolution step 836: f(x)= 3.556528123619122
# differential_evolution step 837: f(x)= 3.556528123619122
# differential_evolution step 838: f(x)= 3.556528123619122
# differential_evolution step 839: f(x)= 3.556528123619122
# differential_evolution step 840: f(x)= 3.556527193822971
# differential_evolution step 841: f(x)= 3.556527193822971
# differential_evolution step 842: f(x)= 3.556527193822971
# differential_evolution step 843: f(x)= 3.556527193822971
# differential_evolution step 844: f(x)= 3.556517832955725
# differential_evolution step 845: f(x)= 3.556517832955725
# differential_evolution step 846: f(x)= 3.556517832955725
# differential_evolution step 847: f(x)= 3.556517832955725
# differential_evolution step 848: f(x)= 3.556517832955725
# differential_evolution step 849: f(x)= 3.556512617798239
# differential_evolution step 850: f(x)= 3.556512617798239
# differential_evolution step 851: f(x)= 3.556512617798239
# differential_evolution step 852: f(x)= 3.556512617798239
# differential_evolution step 853: f(x)= 3.556512617798239
# differential_evolution step 854: f(x)= 3.556512617798239
# differential_evolution step 855: f(x)= 3.556512617798239
# differential_evolution step 856: f(x)= 3.5565113560080666
# differential_evolution step 857: f(x)= 3.5565113560080666
# differential_evolution step 858: f(x)= 3.5565113560080666
# differential_evolution step 859: f(x)= 3.5565113560080666
# differential_evolution step 860: f(x)= 3.5565113560080666
# differential_evolution step 861: f(x)= 3.5565113560080666
# differential_evolution step 862: f(x)= 3.5565113560080666
# differential_evolution step 863: f(x)= 3.5565109015933274
# differential_evolution step 864: f(x)= 3.5565109015933274
# differential_evolution step 865: f(x)= 3.5565096547923196
# differential_evolution step 866: f(x)= 3.5565096547923196
# differential_evolution step 867: f(x)= 3.5565096547923196
# differential_evolution step 868: f(x)= 3.5565096547923196
# differential_evolution step 869: f(x)= 3.5565096547923196
# differential_evolution step 870: f(x)= 3.5565096547923196
# differential_evolution step 871: f(x)= 3.5565096547923196
# differential_evolution step 872: f(x)= 3.5565096547923196
# differential_evolution step 873: f(x)= 3.5565096547923196
# differential_evolution step 874: f(x)= 3.5565096547923196
# differential_evolution step 875: f(x)= 3.5565096547923196
# differential_evolution step 876: f(x)= 3.5565096547923196
# differential_evolution step 877: f(x)= 3.5565047113889228
# differential_evolution step 878: f(x)= 3.5565047113889228
# differential_evolution step 879: f(x)= 3.5565047113889228
# differential_evolution step 880: f(x)= 3.5565040867637077
# differential_evolution step 881: f(x)= 3.5565040867637077
# differential_evolution step 882: f(x)= 3.556502912304836
# differential_evolution step 883: f(x)= 3.556502912304836
# differential_evolution step 884: f(x)= 3.556502912304836
# differential_evolution step 885: f(x)= 3.556502912304836
# differential_evolution step 886: f(x)= 3.556502912304836
# differential_evolution step 887: f(x)= 3.556502912304836
# differential_evolution step 888: f(x)= 3.556502912304836
# differential_evolution step 889: f(x)= 3.556502912304836
# differential_evolution step 890: f(x)= 3.556502912304836
# differential_evolution step 891: f(x)= 3.5565010911087405
# differential_evolution step 892: f(x)= 3.5565010911087405
# differential_evolution step 893: f(x)= 3.5565010911087405
# differential_evolution step 894: f(x)= 3.5565010911087405
# differential_evolution step 895: f(x)= 3.5565010911087405
# differential_evolution step 896: f(x)= 3.5565010911087405
# differential_evolution step 897: f(x)= 3.5565010911087405
# differential_evolution step 898: f(x)= 3.5565010911087405
# differential_evolution step 899: f(x)= 3.5565010911087405
# differential_evolution step 900: f(x)= 3.556498142935711
# differential_evolution step 901: f(x)= 3.556498142935711
# differential_evolution step 902: f(x)= 3.556498142935711
# differential_evolution step 903: f(x)= 3.556498142935711
# differential_evolution step 904: f(x)= 3.556498142935711
# differential_evolution step 905: f(x)= 3.556498142935711
# differential_evolution step 906: f(x)= 3.556498142935711
# differential_evolution step 907: f(x)= 3.556498142935711
# differential_evolution step 908: f(x)= 3.556498142935711
# differential_evolution step 909: f(x)= 3.5564980564063915
# differential_evolution step 910: f(x)= 3.556497135422395
# differential_evolution step 911: f(x)= 3.5564971033658046
# differential_evolution step 912: f(x)= 3.5564971033658046
# differential_evolution step 913: f(x)= 3.5564971033658046
# differential_evolution step 914: f(x)= 3.5564971033658046
# differential_evolution step 915: f(x)= 3.5564971033658046
# differential_evolution step 916: f(x)= 3.5564971033658046
# differential_evolution step 917: f(x)= 3.5564971033658046
# differential_evolution step 918: f(x)= 3.5564971033658046
# differential_evolution step 919: f(x)= 3.5564971033658046
# differential_evolution step 920: f(x)= 3.5564970063714894
# differential_evolution step 921: f(x)= 3.5564970063714894
# differential_evolution step 922: f(x)= 3.5564970063714894
# differential_evolution step 923: f(x)= 3.5564970063714894
# differential_evolution step 924: f(x)= 3.5564965367836665
# differential_evolution step 925: f(x)= 3.556494322959219
# differential_evolution step 926: f(x)= 3.556494322959219
# differential_evolution step 927: f(x)= 3.5564941795218408
# differential_evolution step 928: f(x)= 3.5564941795218408
# differential_evolution step 929: f(x)= 3.5564941795218408
# differential_evolution step 930: f(x)= 3.5564941795218408
# differential_evolution step 931: f(x)= 3.5564941795218408
# differential_evolution step 932: f(x)= 3.5564941795218408
# differential_evolution step 933: f(x)= 3.5564941795218408
# differential_evolution step 934: f(x)= 3.5564941795218408
# differential_evolution step 935: f(x)= 3.5564941795218408
# differential_evolution step 936: f(x)= 3.5564941795218408
# differential_evolution step 937: f(x)= 3.5564941795218408
# differential_evolution step 938: f(x)= 3.5564941795218408
# differential_evolution step 939: f(x)= 3.5564941795218408
# differential_evolution step 940: f(x)= 3.5564941795218408
# differential_evolution step 941: f(x)= 3.5564941795218408
# differential_evolution step 942: f(x)= 3.5564941795218408
# differential_evolution step 943: f(x)= 3.5564941795218408
# differential_evolution step 944: f(x)= 3.5564941795218408
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=8.8179, r_e=2.9486, n=0.5000, x_0=39.8773
# Sérsic 2: I_e=0.4339, r_e=18.3994, n=1.6246, x_0=48.7750
# Sérsic 3: I_e=1.4822, r_e=2.3742, n=0.6748, x_0=57.6336
# Chi quadro minimo: 3.5564927881326467
# True

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=8.8179, r_e=2.9486, n=0.5000, x_0=39.8773
# Sérsic 2: I_e=0.4339, r_e=18.3994, n=1.6246, x_0=48.7750
# Sérsic 3: I_e=1.4822, r_e=2.3742, n=0.6748, x_0=57.6336
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = real_errors_SII)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=7.4838, r_e=3.1511, n=0.6358, x_0=39.9524
# Sérsic 2: I_e=0.3096, r_e=19.7932, n=1.8444, x_0=48.3689
# Sérsic 3: I_e=0.8827, r_e=4.0875, n=1.0314, x_0=57.5609
# [0.24593828 0.05550084 0.02676916 0.04196576 0.05022803 1.61913057
#  0.12039336 0.09012688 0.10797941 0.3572935  0.09479758 0.07278852]
# 0.9289547700575007

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[1])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 8281.051657782655
# differential_evolution step 2: f(x)= 2110.609596144161
# differential_evolution step 3: f(x)= 930.4794288881304
# differential_evolution step 4: f(x)= 428.6446052127554
# differential_evolution step 5: f(x)= 428.6446052127554
# differential_evolution step 6: f(x)= 372.3785613501263
# differential_evolution step 7: f(x)= 181.00069704367544
# differential_evolution step 8: f(x)= 181.00069704367544
# differential_evolution step 9: f(x)= 181.00069704367544
# differential_evolution step 10: f(x)= 91.95352036871763
# differential_evolution step 11: f(x)= 91.95352036871763
# differential_evolution step 12: f(x)= 83.6932312949206
# differential_evolution step 13: f(x)= 83.6932312949206
# differential_evolution step 14: f(x)= 83.6932312949206
# differential_evolution step 15: f(x)= 83.6932312949206
# differential_evolution step 16: f(x)= 83.6932312949206
# differential_evolution step 17: f(x)= 83.6932312949206
# differential_evolution step 18: f(x)= 83.67709956812097
# differential_evolution step 19: f(x)= 83.67709956812097
# differential_evolution step 20: f(x)= 83.67709956812097
# differential_evolution step 21: f(x)= 62.50212977474118
# differential_evolution step 22: f(x)= 62.50212977474118
# differential_evolution step 23: f(x)= 62.50212977474118
# differential_evolution step 24: f(x)= 62.50212977474118
# differential_evolution step 25: f(x)= 58.44924899153396
# differential_evolution step 26: f(x)= 58.44924899153396
# differential_evolution step 27: f(x)= 54.33334418792171
# differential_evolution step 28: f(x)= 38.69685412455787
# differential_evolution step 29: f(x)= 38.69685412455787
# differential_evolution step 30: f(x)= 38.69685412455787
# differential_evolution step 31: f(x)= 38.69685412455787
# differential_evolution step 32: f(x)= 38.69685412455787
# differential_evolution step 33: f(x)= 38.69685412455787
# differential_evolution step 34: f(x)= 38.69685412455787
# differential_evolution step 35: f(x)= 38.69685412455787
# differential_evolution step 36: f(x)= 38.69685412455787
# differential_evolution step 37: f(x)= 38.69685412455787
# differential_evolution step 38: f(x)= 38.69685412455787
# differential_evolution step 39: f(x)= 38.69685412455787
# differential_evolution step 40: f(x)= 38.69685412455787
# differential_evolution step 41: f(x)= 38.69685412455787
# differential_evolution step 42: f(x)= 38.69685412455787
# differential_evolution step 43: f(x)= 38.69685412455787
# differential_evolution step 44: f(x)= 38.69685412455787
# differential_evolution step 45: f(x)= 34.07949816850905
# differential_evolution step 46: f(x)= 34.07949816850905
# differential_evolution step 47: f(x)= 34.07949816850905
# differential_evolution step 48: f(x)= 34.07949816850905
# differential_evolution step 49: f(x)= 33.115344432709136
# differential_evolution step 50: f(x)= 29.184693988612867
# differential_evolution step 51: f(x)= 29.184693988612867
# differential_evolution step 52: f(x)= 29.184693988612867
# differential_evolution step 53: f(x)= 29.184693988612867
# differential_evolution step 54: f(x)= 29.184693988612867
# differential_evolution step 55: f(x)= 29.184693988612867
# differential_evolution step 56: f(x)= 29.184693988612867
# differential_evolution step 57: f(x)= 29.184693988612867
# differential_evolution step 58: f(x)= 29.184693988612867
# differential_evolution step 59: f(x)= 29.184693988612867
# differential_evolution step 60: f(x)= 29.184693988612867
# differential_evolution step 61: f(x)= 29.184693988612867
# differential_evolution step 62: f(x)= 27.928498437048223
# differential_evolution step 63: f(x)= 27.928498437048223
# differential_evolution step 64: f(x)= 27.928498437048223
# differential_evolution step 65: f(x)= 27.369065289916787
# differential_evolution step 66: f(x)= 27.369065289916787
# differential_evolution step 67: f(x)= 27.369065289916787
# differential_evolution step 68: f(x)= 27.369065289916787
# differential_evolution step 69: f(x)= 26.246963396943624
# differential_evolution step 70: f(x)= 26.164074193968094
# differential_evolution step 71: f(x)= 26.164074193968094
# differential_evolution step 72: f(x)= 25.140139153006828
# differential_evolution step 73: f(x)= 25.140139153006828
# differential_evolution step 74: f(x)= 25.140139153006828
# differential_evolution step 75: f(x)= 25.140139153006828
# differential_evolution step 76: f(x)= 25.140139153006828
# differential_evolution step 77: f(x)= 25.140139153006828
# differential_evolution step 78: f(x)= 25.140139153006828
# differential_evolution step 79: f(x)= 25.140139153006828
# differential_evolution step 80: f(x)= 25.140139153006828
# differential_evolution step 81: f(x)= 25.140139153006828
# differential_evolution step 82: f(x)= 24.889951809738726
# differential_evolution step 83: f(x)= 23.99725762044615
# differential_evolution step 84: f(x)= 23.002200978757823
# differential_evolution step 85: f(x)= 23.002200978757823
# differential_evolution step 86: f(x)= 23.002200978757823
# differential_evolution step 87: f(x)= 22.84777296544676
# differential_evolution step 88: f(x)= 22.84777296544676
# differential_evolution step 89: f(x)= 22.84777296544676
# differential_evolution step 90: f(x)= 22.84777296544676
# differential_evolution step 91: f(x)= 22.84777296544676
# differential_evolution step 92: f(x)= 22.45995167220395
# differential_evolution step 93: f(x)= 22.45995167220395
# differential_evolution step 94: f(x)= 22.45995167220395
# differential_evolution step 95: f(x)= 22.45995167220395
# differential_evolution step 96: f(x)= 22.45995167220395
# differential_evolution step 97: f(x)= 22.45995167220395
# differential_evolution step 98: f(x)= 22.45995167220395
# differential_evolution step 99: f(x)= 22.45995167220395
# differential_evolution step 100: f(x)= 22.45995167220395
# differential_evolution step 101: f(x)= 22.45995167220395
# differential_evolution step 102: f(x)= 22.45995167220395
# differential_evolution step 103: f(x)= 22.45995167220395
# differential_evolution step 104: f(x)= 22.45995167220395
# differential_evolution step 105: f(x)= 22.45995167220395
# differential_evolution step 106: f(x)= 22.45995167220395
# differential_evolution step 107: f(x)= 22.45995167220395
# differential_evolution step 108: f(x)= 22.032022459149168
# differential_evolution step 109: f(x)= 22.032022459149168
# differential_evolution step 110: f(x)= 22.032022459149168
# differential_evolution step 111: f(x)= 22.032022459149168
# differential_evolution step 112: f(x)= 22.032022459149168
# differential_evolution step 113: f(x)= 22.032022459149168
# differential_evolution step 114: f(x)= 22.032022459149168
# differential_evolution step 115: f(x)= 22.032022459149168
# differential_evolution step 116: f(x)= 22.032022459149168
# differential_evolution step 117: f(x)= 22.032022459149168
# differential_evolution step 118: f(x)= 22.032022459149168
# differential_evolution step 119: f(x)= 21.931995422072735
# differential_evolution step 120: f(x)= 21.931995422072735
# differential_evolution step 121: f(x)= 21.931995422072735
# differential_evolution step 122: f(x)= 21.931995422072735
# differential_evolution step 123: f(x)= 21.931995422072735
# differential_evolution step 124: f(x)= 21.931995422072735
# differential_evolution step 125: f(x)= 21.931995422072735
# differential_evolution step 126: f(x)= 21.931995422072735
# differential_evolution step 127: f(x)= 21.931995422072735
# differential_evolution step 128: f(x)= 21.931995422072735
# differential_evolution step 129: f(x)= 21.931995422072735
# differential_evolution step 130: f(x)= 21.931995422072735
# differential_evolution step 131: f(x)= 21.931995422072735
# differential_evolution step 132: f(x)= 21.931995422072735
# differential_evolution step 133: f(x)= 21.931995422072735
# differential_evolution step 134: f(x)= 21.37910063997291
# differential_evolution step 135: f(x)= 21.093897193349367
# differential_evolution step 136: f(x)= 21.093897193349367
# differential_evolution step 137: f(x)= 21.093897193349367
# differential_evolution step 138: f(x)= 20.509667258869445
# differential_evolution step 139: f(x)= 20.509667258869445
# differential_evolution step 140: f(x)= 20.509667258869445
# differential_evolution step 141: f(x)= 20.509667258869445
# differential_evolution step 142: f(x)= 19.628630526308616
# differential_evolution step 143: f(x)= 19.628630526308616
# differential_evolution step 144: f(x)= 19.628630526308616
# differential_evolution step 145: f(x)= 19.628630526308616
# differential_evolution step 146: f(x)= 19.628630526308616
# differential_evolution step 147: f(x)= 19.628630526308616
# differential_evolution step 148: f(x)= 19.628630526308616
# differential_evolution step 149: f(x)= 19.628630526308616
# differential_evolution step 150: f(x)= 19.628630526308616
# differential_evolution step 151: f(x)= 19.628630526308616
# differential_evolution step 152: f(x)= 19.628630526308616
# differential_evolution step 153: f(x)= 19.628630526308616
# differential_evolution step 154: f(x)= 19.628630526308616
# differential_evolution step 155: f(x)= 19.628630526308616
# differential_evolution step 156: f(x)= 19.628630526308616
# differential_evolution step 157: f(x)= 19.628630526308616
# differential_evolution step 158: f(x)= 19.628630526308616
# differential_evolution step 159: f(x)= 19.562045293939004
# differential_evolution step 160: f(x)= 19.562045293939004
# differential_evolution step 161: f(x)= 19.562045293939004
# differential_evolution step 162: f(x)= 19.562045293939004
# differential_evolution step 163: f(x)= 19.562045293939004
# differential_evolution step 164: f(x)= 19.562045293939004
# differential_evolution step 165: f(x)= 19.45247414741686
# differential_evolution step 166: f(x)= 19.45247414741686
# differential_evolution step 167: f(x)= 19.45247414741686
# differential_evolution step 168: f(x)= 19.45247414741686
# differential_evolution step 169: f(x)= 19.45247414741686
# differential_evolution step 170: f(x)= 19.45247414741686
# differential_evolution step 171: f(x)= 19.45247414741686
# differential_evolution step 172: f(x)= 19.45247414741686
# differential_evolution step 173: f(x)= 19.45247414741686
# differential_evolution step 174: f(x)= 19.431207405126703
# differential_evolution step 175: f(x)= 19.321259583024545
# differential_evolution step 176: f(x)= 19.321259583024545
# differential_evolution step 177: f(x)= 19.321259583024545
# differential_evolution step 178: f(x)= 19.321259583024545
# differential_evolution step 179: f(x)= 19.321259583024545
# differential_evolution step 180: f(x)= 19.321259583024545
# differential_evolution step 181: f(x)= 19.321259583024545
# differential_evolution step 182: f(x)= 19.321259583024545
# differential_evolution step 183: f(x)= 19.321259583024545
# differential_evolution step 184: f(x)= 19.321259583024545
# differential_evolution step 185: f(x)= 19.321259583024545
# differential_evolution step 186: f(x)= 19.321259583024545
# differential_evolution step 187: f(x)= 19.321259583024545
# differential_evolution step 188: f(x)= 19.321259583024545
# differential_evolution step 189: f(x)= 19.197263467414672
# differential_evolution step 190: f(x)= 19.197263467414672
# differential_evolution step 191: f(x)= 19.197263467414672
# differential_evolution step 192: f(x)= 19.197263467414672
# differential_evolution step 193: f(x)= 19.197263467414672
# differential_evolution step 194: f(x)= 19.197263467414672
# differential_evolution step 195: f(x)= 19.197263467414672
# differential_evolution step 196: f(x)= 19.10235034211889
# differential_evolution step 197: f(x)= 19.10235034211889
# differential_evolution step 198: f(x)= 19.10235034211889
# differential_evolution step 199: f(x)= 19.082326327580045
# differential_evolution step 200: f(x)= 18.970888044542303
# differential_evolution step 201: f(x)= 18.731016658676676
# differential_evolution step 202: f(x)= 18.731016658676676
# differential_evolution step 203: f(x)= 18.731016658676676
# differential_evolution step 204: f(x)= 18.731016658676676
# differential_evolution step 205: f(x)= 18.731016658676676
# differential_evolution step 206: f(x)= 18.731016658676676
# differential_evolution step 207: f(x)= 18.731016658676676
# differential_evolution step 208: f(x)= 18.717908910334472
# differential_evolution step 209: f(x)= 18.557583712105284
# differential_evolution step 210: f(x)= 18.488828159026745
# differential_evolution step 211: f(x)= 18.488828159026745
# differential_evolution step 212: f(x)= 18.488828159026745
# differential_evolution step 213: f(x)= 18.488828159026745
# differential_evolution step 214: f(x)= 18.488828159026745
# differential_evolution step 215: f(x)= 18.488828159026745
# differential_evolution step 216: f(x)= 18.488828159026745
# differential_evolution step 217: f(x)= 18.488828159026745
# differential_evolution step 218: f(x)= 18.488828159026745
# differential_evolution step 219: f(x)= 18.488828159026745
# differential_evolution step 220: f(x)= 18.488828159026745
# differential_evolution step 221: f(x)= 18.488828159026745
# differential_evolution step 222: f(x)= 18.313855668481192
# differential_evolution step 223: f(x)= 18.313855668481192
# differential_evolution step 224: f(x)= 18.313855668481192
# differential_evolution step 225: f(x)= 18.313855668481192
# differential_evolution step 226: f(x)= 18.313855668481192
# differential_evolution step 227: f(x)= 18.313855668481192
# differential_evolution step 228: f(x)= 18.313855668481192
# differential_evolution step 229: f(x)= 18.313855668481192
# differential_evolution step 230: f(x)= 18.313855668481192
# differential_evolution step 231: f(x)= 18.313855668481192
# differential_evolution step 232: f(x)= 18.313855668481192
# differential_evolution step 233: f(x)= 18.313855668481192
# differential_evolution step 234: f(x)= 18.313855668481192
# differential_evolution step 235: f(x)= 18.313855668481192
# differential_evolution step 236: f(x)= 18.313855668481192
# differential_evolution step 237: f(x)= 18.313855668481192
# differential_evolution step 238: f(x)= 18.313855668481192
# differential_evolution step 239: f(x)= 18.313855668481192
# differential_evolution step 240: f(x)= 18.313855668481192
# differential_evolution step 241: f(x)= 18.303872093190375
# differential_evolution step 242: f(x)= 18.299241971439162
# differential_evolution step 243: f(x)= 18.299241971439162
# differential_evolution step 244: f(x)= 18.299241971439162
# differential_evolution step 245: f(x)= 18.231970681203602
# differential_evolution step 246: f(x)= 18.231970681203602
# differential_evolution step 247: f(x)= 18.231970681203602
# differential_evolution step 248: f(x)= 18.189782939595617
# differential_evolution step 249: f(x)= 18.189782939595617
# differential_evolution step 250: f(x)= 18.178617528049454
# differential_evolution step 251: f(x)= 18.178617528049454
# differential_evolution step 252: f(x)= 18.178617528049454
# differential_evolution step 253: f(x)= 18.178617528049454
# differential_evolution step 254: f(x)= 18.178617528049454
# differential_evolution step 255: f(x)= 18.174531023251305
# differential_evolution step 256: f(x)= 18.174531023251305
# differential_evolution step 257: f(x)= 18.174531023251305
# differential_evolution step 258: f(x)= 18.128961891825362
# differential_evolution step 259: f(x)= 18.128961891825362
# differential_evolution step 260: f(x)= 18.128961891825362
# differential_evolution step 261: f(x)= 18.128961891825362
# differential_evolution step 262: f(x)= 18.128961891825362
# differential_evolution step 263: f(x)= 18.128961891825362
# differential_evolution step 264: f(x)= 18.128961891825362
# differential_evolution step 265: f(x)= 18.128961891825362
# differential_evolution step 266: f(x)= 18.128961891825362
# differential_evolution step 267: f(x)= 18.128961891825362
# differential_evolution step 268: f(x)= 18.128961891825362
# differential_evolution step 269: f(x)= 18.128961891825362
# differential_evolution step 270: f(x)= 18.128961891825362
# differential_evolution step 271: f(x)= 18.128961891825362
# differential_evolution step 272: f(x)= 18.128961891825362
# differential_evolution step 273: f(x)= 18.128961891825362
# differential_evolution step 274: f(x)= 18.128961891825362
# differential_evolution step 275: f(x)= 18.128961891825362
# differential_evolution step 276: f(x)= 18.128961891825362
# differential_evolution step 277: f(x)= 18.128961891825362
# differential_evolution step 278: f(x)= 18.128961891825362
# differential_evolution step 279: f(x)= 18.128961891825362
# differential_evolution step 280: f(x)= 18.128961891825362
# differential_evolution step 281: f(x)= 18.128961891825362
# differential_evolution step 282: f(x)= 18.12295211305714
# differential_evolution step 283: f(x)= 18.12295211305714
# differential_evolution step 284: f(x)= 18.12295211305714
# differential_evolution step 285: f(x)= 18.12295211305714
# differential_evolution step 286: f(x)= 18.12295211305714
# differential_evolution step 287: f(x)= 18.12295211305714
# differential_evolution step 288: f(x)= 18.12295211305714
# differential_evolution step 289: f(x)= 18.12295211305714
# differential_evolution step 290: f(x)= 18.09400363333784
# differential_evolution step 291: f(x)= 18.09400363333784
# differential_evolution step 292: f(x)= 18.09400363333784
# differential_evolution step 293: f(x)= 18.09400363333784
# differential_evolution step 294: f(x)= 18.09400363333784
# differential_evolution step 295: f(x)= 18.09400363333784
# differential_evolution step 296: f(x)= 18.09400363333784
# differential_evolution step 297: f(x)= 18.09400363333784
# differential_evolution step 298: f(x)= 18.09400363333784
# differential_evolution step 299: f(x)= 18.09400363333784
# differential_evolution step 300: f(x)= 18.09400363333784
# differential_evolution step 301: f(x)= 18.09400363333784
# differential_evolution step 302: f(x)= 18.09400363333784
# differential_evolution step 303: f(x)= 18.09400363333784
# differential_evolution step 304: f(x)= 18.09400363333784
# differential_evolution step 305: f(x)= 18.09400363333784
# differential_evolution step 306: f(x)= 18.09400363333784
# differential_evolution step 307: f(x)= 18.09400363333784
# differential_evolution step 308: f(x)= 18.09400363333784
# differential_evolution step 309: f(x)= 18.09400363333784
# differential_evolution step 310: f(x)= 18.09400363333784
# differential_evolution step 311: f(x)= 18.09400363333784
# differential_evolution step 312: f(x)= 18.08353407616279
# differential_evolution step 313: f(x)= 18.08353407616279
# differential_evolution step 314: f(x)= 18.08353407616279
# differential_evolution step 315: f(x)= 18.08353407616279
# differential_evolution step 316: f(x)= 18.08353407616279
# differential_evolution step 317: f(x)= 18.08353407616279
# differential_evolution step 318: f(x)= 18.08353407616279
# differential_evolution step 319: f(x)= 18.08353407616279
# differential_evolution step 320: f(x)= 18.08353407616279
# differential_evolution step 321: f(x)= 18.073405153100857
# differential_evolution step 322: f(x)= 18.073405153100857
# differential_evolution step 323: f(x)= 18.058091798312958
# differential_evolution step 324: f(x)= 18.058091798312958
# differential_evolution step 325: f(x)= 18.058091798312958
# differential_evolution step 326: f(x)= 18.058091798312958
# differential_evolution step 327: f(x)= 18.058091798312958
# differential_evolution step 328: f(x)= 18.058091798312958
# differential_evolution step 329: f(x)= 18.058091798312958
# differential_evolution step 330: f(x)= 18.058091798312958
# differential_evolution step 331: f(x)= 18.058091798312958
# differential_evolution step 332: f(x)= 18.058091798312958
# differential_evolution step 333: f(x)= 18.058091798312958
# differential_evolution step 334: f(x)= 18.058091798312958
# differential_evolution step 335: f(x)= 18.058091798312958
# differential_evolution step 336: f(x)= 18.058091798312958
# differential_evolution step 337: f(x)= 18.058091798312958
# differential_evolution step 338: f(x)= 18.058091798312958
# differential_evolution step 339: f(x)= 18.058091798312958
# differential_evolution step 340: f(x)= 18.058091798312958
# differential_evolution step 341: f(x)= 18.058091798312958
# differential_evolution step 342: f(x)= 18.058091798312958
# differential_evolution step 343: f(x)= 18.058091798312958
# differential_evolution step 344: f(x)= 18.058091798312958
# differential_evolution step 345: f(x)= 18.058091798312958
# differential_evolution step 346: f(x)= 18.058091798312958
# differential_evolution step 347: f(x)= 18.058091798312958
# differential_evolution step 348: f(x)= 18.058091798312958
# differential_evolution step 349: f(x)= 18.058091798312958
# differential_evolution step 350: f(x)= 18.058091798312958
# differential_evolution step 351: f(x)= 18.058091798312958
# differential_evolution step 352: f(x)= 18.058091798312958
# differential_evolution step 353: f(x)= 18.058091798312958
# differential_evolution step 354: f(x)= 18.058091798312958
# differential_evolution step 355: f(x)= 18.058091798312958
# differential_evolution step 356: f(x)= 18.058091798312958
# differential_evolution step 357: f(x)= 18.058091798312958
# differential_evolution step 358: f(x)= 18.058091798312958
# differential_evolution step 359: f(x)= 18.058091798312958
# differential_evolution step 360: f(x)= 18.058091798312958
# differential_evolution step 361: f(x)= 18.058091798312958
# differential_evolution step 362: f(x)= 18.058091798312958
# differential_evolution step 363: f(x)= 18.058091798312958
# differential_evolution step 364: f(x)= 18.058091798312958
# differential_evolution step 365: f(x)= 18.058091798312958
# differential_evolution step 366: f(x)= 18.058091798312958
# differential_evolution step 367: f(x)= 18.058091798312958
# differential_evolution step 368: f(x)= 18.058091798312958
# differential_evolution step 369: f(x)= 18.058091798312958
# differential_evolution step 370: f(x)= 18.058091798312958
# differential_evolution step 371: f(x)= 18.058091798312958
# differential_evolution step 372: f(x)= 18.058091798312958
# differential_evolution step 373: f(x)= 18.058091798312958
# differential_evolution step 374: f(x)= 18.058091798312958
# differential_evolution step 375: f(x)= 18.058091798312958
# differential_evolution step 376: f(x)= 18.058091798312958
# differential_evolution step 377: f(x)= 18.058091798312958
# differential_evolution step 378: f(x)= 18.058091798312958
# differential_evolution step 379: f(x)= 18.058091798312958
# differential_evolution step 380: f(x)= 18.058091798312958
# differential_evolution step 381: f(x)= 18.058091798312958
# differential_evolution step 382: f(x)= 18.058091798312958
# differential_evolution step 383: f(x)= 18.058091798312958
# differential_evolution step 384: f(x)= 18.05566210195809
# differential_evolution step 385: f(x)= 18.05566210195809
# differential_evolution step 386: f(x)= 18.05566210195809
# differential_evolution step 387: f(x)= 18.05566210195809
# differential_evolution step 388: f(x)= 18.05566210195809
# differential_evolution step 389: f(x)= 18.05566210195809
# differential_evolution step 390: f(x)= 18.05566210195809
# differential_evolution step 391: f(x)= 18.05566210195809
# differential_evolution step 392: f(x)= 18.054348313982764
# differential_evolution step 393: f(x)= 18.054348313982764
# differential_evolution step 394: f(x)= 18.054209205149814
# differential_evolution step 395: f(x)= 18.054209205149814
# differential_evolution step 396: f(x)= 18.054209205149814
# differential_evolution step 397: f(x)= 18.054209205149814
# differential_evolution step 398: f(x)= 18.054209205149814
# differential_evolution step 399: f(x)= 18.05302283759851
# differential_evolution step 400: f(x)= 18.05302283759851
# differential_evolution step 401: f(x)= 18.051275382351402
# differential_evolution step 402: f(x)= 18.05101734467531
# differential_evolution step 403: f(x)= 18.05101734467531
# differential_evolution step 404: f(x)= 18.05101734467531
# differential_evolution step 405: f(x)= 18.05101734467531
# differential_evolution step 406: f(x)= 18.05101734467531
# differential_evolution step 407: f(x)= 18.05101734467531
# differential_evolution step 408: f(x)= 18.05101734467531
# differential_evolution step 409: f(x)= 18.05101734467531
# differential_evolution step 410: f(x)= 18.05101734467531
# differential_evolution step 411: f(x)= 18.05101734467531
# differential_evolution step 412: f(x)= 18.05101734467531
# differential_evolution step 413: f(x)= 18.05101734467531
# differential_evolution step 414: f(x)= 18.05101734467531
# differential_evolution step 415: f(x)= 18.05101734467531
# differential_evolution step 416: f(x)= 18.05101734467531
# differential_evolution step 417: f(x)= 18.05101734467531
# differential_evolution step 418: f(x)= 18.04991218653529
# differential_evolution step 419: f(x)= 18.04991218653529
# differential_evolution step 420: f(x)= 18.049902102326495
# differential_evolution step 421: f(x)= 18.049902102326495
# differential_evolution step 422: f(x)= 18.049741459240334
# differential_evolution step 423: f(x)= 18.049741459240334
# differential_evolution step 424: f(x)= 18.049741459240334
# differential_evolution step 425: f(x)= 18.049741459240334
# differential_evolution step 426: f(x)= 18.049741459240334
# differential_evolution step 427: f(x)= 18.049741459240334
# differential_evolution step 428: f(x)= 18.049741459240334
# differential_evolution step 429: f(x)= 18.049741459240334
# differential_evolution step 430: f(x)= 18.049741459240334
# differential_evolution step 431: f(x)= 18.048878141575717
# differential_evolution step 432: f(x)= 18.048878141575717
# differential_evolution step 433: f(x)= 18.048878141575717
# differential_evolution step 434: f(x)= 18.048878141575717
# differential_evolution step 435: f(x)= 18.048878141575717
# differential_evolution step 436: f(x)= 18.048878141575717
# differential_evolution step 437: f(x)= 18.048878141575717
# differential_evolution step 438: f(x)= 18.048878141575717
# differential_evolution step 439: f(x)= 18.048878141575717
# differential_evolution step 440: f(x)= 18.048878141575717
# differential_evolution step 441: f(x)= 18.04866156655365
# differential_evolution step 442: f(x)= 18.04866156655365
# differential_evolution step 443: f(x)= 18.04866156655365
# differential_evolution step 444: f(x)= 18.04866156655365
# differential_evolution step 445: f(x)= 18.04866156655365
# differential_evolution step 446: f(x)= 18.04866156655365
# differential_evolution step 447: f(x)= 18.04866156655365
# differential_evolution step 448: f(x)= 18.047891556856754
# differential_evolution step 449: f(x)= 18.047891556856754
# differential_evolution step 450: f(x)= 18.047891556856754
# differential_evolution step 451: f(x)= 18.047891556856754
# differential_evolution step 452: f(x)= 18.047891556856754
# differential_evolution step 453: f(x)= 18.047891556856754
# differential_evolution step 454: f(x)= 18.047891556856754
# differential_evolution step 455: f(x)= 18.047891556856754
# differential_evolution step 456: f(x)= 18.047891556856754
# differential_evolution step 457: f(x)= 18.047610021956206
# differential_evolution step 458: f(x)= 18.047610021956206
# differential_evolution step 459: f(x)= 18.047610021956206
# differential_evolution step 460: f(x)= 18.047610021956206
# differential_evolution step 461: f(x)= 18.047610021956206
# differential_evolution step 462: f(x)= 18.047610021956206
# differential_evolution step 463: f(x)= 18.047610021956206
# differential_evolution step 464: f(x)= 18.047610021956206
# differential_evolution step 465: f(x)= 18.047610021956206
# differential_evolution step 466: f(x)= 18.04704220503086
# differential_evolution step 467: f(x)= 18.04704220503086
# differential_evolution step 468: f(x)= 18.04704220503086
# differential_evolution step 469: f(x)= 18.04704220503086
# differential_evolution step 470: f(x)= 18.04704220503086
# differential_evolution step 471: f(x)= 18.04704220503086
# differential_evolution step 472: f(x)= 18.04704220503086
# differential_evolution step 473: f(x)= 18.04704220503086
# differential_evolution step 474: f(x)= 18.04704220503086
# differential_evolution step 475: f(x)= 18.04704220503086
# differential_evolution step 476: f(x)= 18.04704220503086
# differential_evolution step 477: f(x)= 18.04704220503086
# differential_evolution step 478: f(x)= 18.04704220503086
# differential_evolution step 479: f(x)= 18.046837586971677
# differential_evolution step 480: f(x)= 18.046837586971677
# differential_evolution step 481: f(x)= 18.046837586971677
# differential_evolution step 482: f(x)= 18.046837586971677
# differential_evolution step 483: f(x)= 18.046837586971677
# differential_evolution step 484: f(x)= 18.046837586971677
# differential_evolution step 485: f(x)= 18.04662160139019
# differential_evolution step 486: f(x)= 18.04662160139019
# differential_evolution step 487: f(x)= 18.04662160139019
# differential_evolution step 488: f(x)= 18.04662160139019
# differential_evolution step 489: f(x)= 18.04662160139019
# differential_evolution step 490: f(x)= 18.04662160139019
# differential_evolution step 491: f(x)= 18.04662160139019
# differential_evolution step 492: f(x)= 18.04662160139019
# differential_evolution step 493: f(x)= 18.04662160139019
# differential_evolution step 494: f(x)= 18.04662160139019
# differential_evolution step 495: f(x)= 18.04662160139019
# differential_evolution step 496: f(x)= 18.04662160139019
# differential_evolution step 497: f(x)= 18.04662160139019
# differential_evolution step 498: f(x)= 18.04662160139019
# differential_evolution step 499: f(x)= 18.04662160139019
# differential_evolution step 500: f(x)= 18.04662160139019
# differential_evolution step 501: f(x)= 18.046367877240584
# differential_evolution step 502: f(x)= 18.046367877240584
# differential_evolution step 503: f(x)= 18.046367877240584
# differential_evolution step 504: f(x)= 18.046367877240584
# differential_evolution step 505: f(x)= 18.046367877240584
# differential_evolution step 506: f(x)= 18.046367877240584
# differential_evolution step 507: f(x)= 18.046367877240584
# differential_evolution step 508: f(x)= 18.046367877240584
# differential_evolution step 509: f(x)= 18.046367877240584
# differential_evolution step 510: f(x)= 18.046367877240584
# differential_evolution step 511: f(x)= 18.046367877240584
# differential_evolution step 512: f(x)= 18.046367877240584
# differential_evolution step 513: f(x)= 18.046367877240584
# differential_evolution step 514: f(x)= 18.04630700823499
# differential_evolution step 515: f(x)= 18.04630700823499
# differential_evolution step 516: f(x)= 18.046254331625274
# differential_evolution step 517: f(x)= 18.046254331625274
# differential_evolution step 518: f(x)= 18.046254331625274
# differential_evolution step 519: f(x)= 18.046254331625274
# differential_evolution step 520: f(x)= 18.046254331625274
# differential_evolution step 521: f(x)= 18.046254331625274
# differential_evolution step 522: f(x)= 18.046254331625274
# differential_evolution step 523: f(x)= 18.046254331625274
# differential_evolution step 524: f(x)= 18.046254331625274
# differential_evolution step 525: f(x)= 18.046254331625274
# differential_evolution step 526: f(x)= 18.046254331625274
# differential_evolution step 527: f(x)= 18.046254331625274
# differential_evolution step 528: f(x)= 18.046254331625274
# differential_evolution step 529: f(x)= 18.046254331625274
# differential_evolution step 530: f(x)= 18.046254007538103
# differential_evolution step 531: f(x)= 18.046254007538103
# differential_evolution step 532: f(x)= 18.046254007538103
# differential_evolution step 533: f(x)= 18.046224391071018
# differential_evolution step 534: f(x)= 18.046126678732776
# differential_evolution step 535: f(x)= 18.046126678732776
# differential_evolution step 536: f(x)= 18.046126678732776
# differential_evolution step 537: f(x)= 18.046126678732776
# differential_evolution step 538: f(x)= 18.046126678732776
# differential_evolution step 539: f(x)= 18.046126678732776
# differential_evolution step 540: f(x)= 18.046126678732776
# differential_evolution step 541: f(x)= 18.046126678732776
# differential_evolution step 542: f(x)= 18.046126678732776
# differential_evolution step 543: f(x)= 18.046126678732776
# differential_evolution step 544: f(x)= 18.046126678732776
# differential_evolution step 545: f(x)= 18.046126678732776
# differential_evolution step 546: f(x)= 18.046126678732776
# differential_evolution step 547: f(x)= 18.04611492420853
# differential_evolution step 548: f(x)= 18.046107210165815
# differential_evolution step 549: f(x)= 18.046107210165815
# differential_evolution step 550: f(x)= 18.046107210165815
# differential_evolution step 551: f(x)= 18.046107210165815
# differential_evolution step 552: f(x)= 18.046107210165815
# differential_evolution step 553: f(x)= 18.046107210165815
# differential_evolution step 554: f(x)= 18.046107210165815
# differential_evolution step 555: f(x)= 18.046107210165815
# differential_evolution step 556: f(x)= 18.046107210165815
# differential_evolution step 557: f(x)= 18.046107210165815
# differential_evolution step 558: f(x)= 18.046107210165815
# differential_evolution step 559: f(x)= 18.046107210165815
# differential_evolution step 560: f(x)= 18.046107210165815
# differential_evolution step 561: f(x)= 18.046107210165815
# differential_evolution step 562: f(x)= 18.046107210165815
# differential_evolution step 563: f(x)= 18.046107210165815
# differential_evolution step 564: f(x)= 18.046107210165815
# differential_evolution step 565: f(x)= 18.046107210165815
# differential_evolution step 566: f(x)= 18.046107210165815
# differential_evolution step 567: f(x)= 18.046107210165815
# differential_evolution step 568: f(x)= 18.046095332557925
# differential_evolution step 569: f(x)= 18.046081024238422
# differential_evolution step 570: f(x)= 18.046081024238422
# differential_evolution step 571: f(x)= 18.04607007716779
# differential_evolution step 572: f(x)= 18.04607007716779
# differential_evolution step 573: f(x)= 18.04607007716779
# differential_evolution step 574: f(x)= 18.04605057907362
# differential_evolution step 575: f(x)= 18.04600084193553
# differential_evolution step 576: f(x)= 18.04600084193553
# differential_evolution step 577: f(x)= 18.04600084193553
# differential_evolution step 578: f(x)= 18.04600084193553
# differential_evolution step 579: f(x)= 18.04600084193553
# differential_evolution step 580: f(x)= 18.04600084193553
# differential_evolution step 581: f(x)= 18.04600084193553
# differential_evolution step 582: f(x)= 18.04600084193553
# differential_evolution step 583: f(x)= 18.04600084193553
# differential_evolution step 584: f(x)= 18.04600084193553
# differential_evolution step 585: f(x)= 18.04600084193553
# differential_evolution step 586: f(x)= 18.04600084193553
# differential_evolution step 587: f(x)= 18.04600084193553
# differential_evolution step 588: f(x)= 18.04600084193553
# differential_evolution step 589: f(x)= 18.04600084193553
# differential_evolution step 590: f(x)= 18.04600084193553
# differential_evolution step 591: f(x)= 18.04600084193553
# differential_evolution step 592: f(x)= 18.04600084193553
# differential_evolution step 593: f(x)= 18.04600084193553
# differential_evolution step 594: f(x)= 18.04600084193553
# differential_evolution step 595: f(x)= 18.04600084193553
# differential_evolution step 596: f(x)= 18.04600084193553
# differential_evolution step 597: f(x)= 18.04600084193553
# differential_evolution step 598: f(x)= 18.04600084193553
# differential_evolution step 599: f(x)= 18.04600084193553
# differential_evolution step 600: f(x)= 18.04600084193553
# differential_evolution step 601: f(x)= 18.04600084193553
# differential_evolution step 602: f(x)= 18.04600084193553
# differential_evolution step 603: f(x)= 18.04600084193553
# differential_evolution step 604: f(x)= 18.04600084193553
# differential_evolution step 605: f(x)= 18.04600084193553
# differential_evolution step 606: f(x)= 18.04600084193553
# differential_evolution step 607: f(x)= 18.04600084193553
# differential_evolution step 608: f(x)= 18.04600084193553
# differential_evolution step 609: f(x)= 18.04600084193553
# differential_evolution step 610: f(x)= 18.04600084193553
# differential_evolution step 611: f(x)= 18.04600084193553
# differential_evolution step 612: f(x)= 18.04600084193553
# differential_evolution step 613: f(x)= 18.04600084193553
# differential_evolution step 614: f(x)= 18.045992994947767
# differential_evolution step 615: f(x)= 18.045992994947767
# differential_evolution step 616: f(x)= 18.045992994947767
# differential_evolution step 617: f(x)= 18.045987410597554
# differential_evolution step 618: f(x)= 18.045987410597554
# differential_evolution step 619: f(x)= 18.045987410597554
# differential_evolution step 620: f(x)= 18.045987410597554
# differential_evolution step 621: f(x)= 18.045987410597554
# differential_evolution step 622: f(x)= 18.045987410597554
# differential_evolution step 623: f(x)= 18.04598624678069
# differential_evolution step 624: f(x)= 18.04598624678069
# differential_evolution step 625: f(x)= 18.04598624678069
# differential_evolution step 626: f(x)= 18.04598624678069
# differential_evolution step 627: f(x)= 18.04598624678069
# differential_evolution step 628: f(x)= 18.04598624678069
# differential_evolution step 629: f(x)= 18.04598624678069
# differential_evolution step 630: f(x)= 18.04598624678069
# differential_evolution step 631: f(x)= 18.04598624678069
# differential_evolution step 632: f(x)= 18.04598624678069
# differential_evolution step 633: f(x)= 18.04598066661394
# differential_evolution step 634: f(x)= 18.04598066661394
# differential_evolution step 635: f(x)= 18.045980228501815
# differential_evolution step 636: f(x)= 18.045980228501815
# differential_evolution step 637: f(x)= 18.045979166536313
# differential_evolution step 638: f(x)= 18.045979166536313
# differential_evolution step 639: f(x)= 18.04597322790089
# differential_evolution step 640: f(x)= 18.045962860261522
# differential_evolution step 641: f(x)= 18.045962860261522
# differential_evolution step 642: f(x)= 18.04596257144948
# differential_evolution step 643: f(x)= 18.04596257144948
# differential_evolution step 644: f(x)= 18.04596257144948
# differential_evolution step 645: f(x)= 18.04596257144948
# differential_evolution step 646: f(x)= 18.04596257144948
# differential_evolution step 647: f(x)= 18.04596257144948
# differential_evolution step 648: f(x)= 18.04596257144948
# differential_evolution step 649: f(x)= 18.04596257144948
# differential_evolution step 650: f(x)= 18.04596257144948
# differential_evolution step 651: f(x)= 18.04596257144948
# differential_evolution step 652: f(x)= 18.04596257144948
# differential_evolution step 653: f(x)= 18.04596257144948
# differential_evolution step 654: f(x)= 18.04596257144948
# differential_evolution step 655: f(x)= 18.045960745912534
# differential_evolution step 656: f(x)= 18.045960745912534
# differential_evolution step 657: f(x)= 18.045956418729823
# differential_evolution step 658: f(x)= 18.045956418729823
# differential_evolution step 659: f(x)= 18.045956418729823
# differential_evolution step 660: f(x)= 18.045956418729823
# differential_evolution step 661: f(x)= 18.045956418729823
# differential_evolution step 662: f(x)= 18.045956418729823
# differential_evolution step 663: f(x)= 18.045956418729823
# differential_evolution step 664: f(x)= 18.045956418729823
# differential_evolution step 665: f(x)= 18.045956418729823
# differential_evolution step 666: f(x)= 18.045956418729823
# differential_evolution step 667: f(x)= 18.045956418729823
# differential_evolution step 668: f(x)= 18.045956418729823
# differential_evolution step 669: f(x)= 18.045956418729823
# differential_evolution step 670: f(x)= 18.045956418729823
# differential_evolution step 671: f(x)= 18.045956418729823
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=4.3098, r_e=3.9320, n=0.9781, x_0=40.0524
# Sérsic 2: I_e=2.3988, r_e=10.6970, n=0.1000, x_0=49.7750
# Sérsic 3: I_e=0.0485, r_e=50.0000, n=2.6559, x_0=58.1217
# Chi quadro minimo: 18.045940427023048
# True

# %%
# Plots:
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=4.3098, r_e=3.9320, n=0.9781, x_0=40.0524
# Sérsic 2: I_e=2.3988, r_e=10.6970, n=0.1000, x_0=49.7750
# Sérsic 3: I_e=0.0485, r_e=50.0000, n=2.6559, x_0=58.1217
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = real_errors_OIII)#, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.7952, r_e=4.9462, n=1.3709, x_0=40.2046
# Sérsic 2: I_e=2.1087, r_e=9.3329, n=0.1456, x_0=49.8742
# Sérsic 3: I_e=0.0274, r_e=77.3932, n=3.2190, x_0=59.0683
# [7.22750081e-01 5.75668711e-01 2.02630887e-01 1.58224554e-01
#  1.63450559e-01 1.78470946e+00 7.30260734e-02 1.11841561e+00
#  6.36270386e-02 1.24330717e+02 2.14261712e+00 1.65904254e-03]
# 4.376424457731541

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[0])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 153953.7874200266
# differential_evolution step 2: f(x)= 109324.04290569546
# differential_evolution step 3: f(x)= 98604.93302083401
# differential_evolution step 4: f(x)= 58872.58262316865
# differential_evolution step 5: f(x)= 58872.58262316865
# differential_evolution step 6: f(x)= 54897.16799713961
# differential_evolution step 7: f(x)= 54897.16799713961
# differential_evolution step 8: f(x)= 28382.272294327286
# differential_evolution step 9: f(x)= 18862.087183981963
# differential_evolution step 10: f(x)= 16207.679521975408
# differential_evolution step 11: f(x)= 16207.679521975408
# differential_evolution step 12: f(x)= 15680.816591459727
# differential_evolution step 13: f(x)= 8422.251241700831
# differential_evolution step 14: f(x)= 6358.156147918384
# differential_evolution step 15: f(x)= 6358.156147918384
# differential_evolution step 16: f(x)= 6358.156147918384
# differential_evolution step 17: f(x)= 6358.156147918384
# differential_evolution step 18: f(x)= 6358.156147918384
# differential_evolution step 19: f(x)= 6358.156147918384
# differential_evolution step 20: f(x)= 6358.156147918384
# differential_evolution step 21: f(x)= 6358.156147918384
# differential_evolution step 22: f(x)= 6358.156147918384
# differential_evolution step 23: f(x)= 6339.8877854301445
# differential_evolution step 24: f(x)= 6339.8877854301445
# differential_evolution step 25: f(x)= 6339.8877854301445
# differential_evolution step 26: f(x)= 4696.8372442298505
# differential_evolution step 27: f(x)= 4696.8372442298505
# differential_evolution step 28: f(x)= 4696.8372442298505
# differential_evolution step 29: f(x)= 4696.8372442298505
# differential_evolution step 30: f(x)= 4696.8372442298505
# differential_evolution step 31: f(x)= 4696.8372442298505
# differential_evolution step 32: f(x)= 4696.8372442298505
# differential_evolution step 33: f(x)= 4696.8372442298505
# differential_evolution step 34: f(x)= 4696.8372442298505
# differential_evolution step 35: f(x)= 4375.4637670925795
# differential_evolution step 36: f(x)= 4375.4637670925795
# differential_evolution step 37: f(x)= 4375.4637670925795
# differential_evolution step 38: f(x)= 3597.1048430148544
# differential_evolution step 39: f(x)= 3597.1048430148544
# differential_evolution step 40: f(x)= 3597.1048430148544
# differential_evolution step 41: f(x)= 3597.1048430148544
# differential_evolution step 42: f(x)= 3597.1048430148544
# differential_evolution step 43: f(x)= 2986.9359929986717
# differential_evolution step 44: f(x)= 2866.955424857253
# differential_evolution step 45: f(x)= 2130.738827850581
# differential_evolution step 46: f(x)= 2130.738827850581
# differential_evolution step 47: f(x)= 2130.738827850581
# differential_evolution step 48: f(x)= 2130.738827850581
# differential_evolution step 49: f(x)= 2030.7200017098608
# differential_evolution step 50: f(x)= 2030.7200017098608
# differential_evolution step 51: f(x)= 2030.7200017098608
# differential_evolution step 52: f(x)= 1363.15553425185
# differential_evolution step 53: f(x)= 1363.15553425185
# differential_evolution step 54: f(x)= 1363.15553425185
# differential_evolution step 55: f(x)= 1363.15553425185
# differential_evolution step 56: f(x)= 1363.15553425185
# differential_evolution step 57: f(x)= 1363.15553425185
# differential_evolution step 58: f(x)= 1363.15553425185
# differential_evolution step 59: f(x)= 1363.15553425185
# differential_evolution step 60: f(x)= 1363.15553425185
# differential_evolution step 61: f(x)= 1103.1707896694172
# differential_evolution step 62: f(x)= 1027.798623732143
# differential_evolution step 63: f(x)= 1027.798623732143
# differential_evolution step 64: f(x)= 1027.798623732143
# differential_evolution step 65: f(x)= 1027.798623732143
# differential_evolution step 66: f(x)= 1027.798623732143
# differential_evolution step 67: f(x)= 1027.798623732143
# differential_evolution step 68: f(x)= 652.779625273526
# differential_evolution step 69: f(x)= 652.779625273526
# differential_evolution step 70: f(x)= 652.779625273526
# differential_evolution step 71: f(x)= 652.779625273526
# differential_evolution step 72: f(x)= 652.779625273526
# differential_evolution step 73: f(x)= 652.779625273526
# differential_evolution step 74: f(x)= 652.779625273526
# differential_evolution step 75: f(x)= 652.779625273526
# differential_evolution step 76: f(x)= 652.779625273526
# differential_evolution step 77: f(x)= 652.779625273526
# differential_evolution step 78: f(x)= 652.779625273526
# differential_evolution step 79: f(x)= 625.1334268291133
# differential_evolution step 80: f(x)= 604.1076812790994
# differential_evolution step 81: f(x)= 525.4708086678846
# differential_evolution step 82: f(x)= 525.4708086678846
# differential_evolution step 83: f(x)= 525.4708086678846
# differential_evolution step 84: f(x)= 525.4708086678846
# differential_evolution step 85: f(x)= 525.4708086678846
# differential_evolution step 86: f(x)= 525.4708086678846
# differential_evolution step 87: f(x)= 525.4708086678846
# differential_evolution step 88: f(x)= 466.20103702875286
# differential_evolution step 89: f(x)= 466.20103702875286
# differential_evolution step 90: f(x)= 466.20103702875286
# differential_evolution step 91: f(x)= 466.20103702875286
# differential_evolution step 92: f(x)= 466.20103702875286
# differential_evolution step 93: f(x)= 466.20103702875286
# differential_evolution step 94: f(x)= 466.20103702875286
# differential_evolution step 95: f(x)= 457.8141092263848
# differential_evolution step 96: f(x)= 457.8141092263848
# differential_evolution step 97: f(x)= 457.8141092263848
# differential_evolution step 98: f(x)= 457.8141092263848
# differential_evolution step 99: f(x)= 457.8141092263848
# differential_evolution step 100: f(x)= 457.8141092263848
# differential_evolution step 101: f(x)= 457.8141092263848
# differential_evolution step 102: f(x)= 457.8141092263848
# differential_evolution step 103: f(x)= 436.20865615200285
# differential_evolution step 104: f(x)= 436.20865615200285
# differential_evolution step 105: f(x)= 436.20865615200285
# differential_evolution step 106: f(x)= 436.20865615200285
# differential_evolution step 107: f(x)= 402.7965166973498
# differential_evolution step 108: f(x)= 402.7965166973498
# differential_evolution step 109: f(x)= 402.7965166973498
# differential_evolution step 110: f(x)= 402.7965166973498
# differential_evolution step 111: f(x)= 402.7965166973498
# differential_evolution step 112: f(x)= 402.7965166973498
# differential_evolution step 113: f(x)= 402.1541162798765
# differential_evolution step 114: f(x)= 402.1541162798765
# differential_evolution step 115: f(x)= 402.1541162798765
# differential_evolution step 116: f(x)= 402.1541162798765
# differential_evolution step 117: f(x)= 402.1541162798765
# differential_evolution step 118: f(x)= 400.18920911657125
# differential_evolution step 119: f(x)= 400.18920911657125
# differential_evolution step 120: f(x)= 400.18920911657125
# differential_evolution step 121: f(x)= 400.18920911657125
# differential_evolution step 122: f(x)= 395.0933946208299
# differential_evolution step 123: f(x)= 395.0933946208299
# differential_evolution step 124: f(x)= 395.0933946208299
# differential_evolution step 125: f(x)= 394.09630630508167
# differential_evolution step 126: f(x)= 394.09630630508167
# differential_evolution step 127: f(x)= 394.09630630508167
# differential_evolution step 128: f(x)= 394.09630630508167
# differential_evolution step 129: f(x)= 382.03473040277476
# differential_evolution step 130: f(x)= 382.03473040277476
# differential_evolution step 131: f(x)= 382.03473040277476
# differential_evolution step 132: f(x)= 382.03473040277476
# differential_evolution step 133: f(x)= 382.03473040277476
# differential_evolution step 134: f(x)= 382.03473040277476
# differential_evolution step 135: f(x)= 382.03473040277476
# differential_evolution step 136: f(x)= 382.03473040277476
# differential_evolution step 137: f(x)= 382.03473040277476
# differential_evolution step 138: f(x)= 382.03473040277476
# differential_evolution step 139: f(x)= 382.03473040277476
# differential_evolution step 140: f(x)= 382.03473040277476
# differential_evolution step 141: f(x)= 382.03473040277476
# differential_evolution step 142: f(x)= 382.03473040277476
# differential_evolution step 143: f(x)= 382.03473040277476
# differential_evolution step 144: f(x)= 376.1602512472294
# differential_evolution step 145: f(x)= 376.1602512472294
# differential_evolution step 146: f(x)= 376.1602512472294
# differential_evolution step 147: f(x)= 376.1602512472294
# differential_evolution step 148: f(x)= 376.1602512472294
# differential_evolution step 149: f(x)= 376.1602512472294
# differential_evolution step 150: f(x)= 376.1602512472294
# differential_evolution step 151: f(x)= 376.1602512472294
# differential_evolution step 152: f(x)= 376.1602512472294
# differential_evolution step 153: f(x)= 369.8033575119023
# differential_evolution step 154: f(x)= 369.8033575119023
# differential_evolution step 155: f(x)= 369.8033575119023
# differential_evolution step 156: f(x)= 369.8033575119023
# differential_evolution step 157: f(x)= 369.8033575119023
# differential_evolution step 158: f(x)= 369.8033575119023
# differential_evolution step 159: f(x)= 369.8033575119023
# differential_evolution step 160: f(x)= 369.8033575119023
# differential_evolution step 161: f(x)= 369.8033575119023
# differential_evolution step 162: f(x)= 369.8033575119023
# differential_evolution step 163: f(x)= 369.8033575119023
# differential_evolution step 164: f(x)= 369.8033575119023
# differential_evolution step 165: f(x)= 369.8033575119023
# differential_evolution step 166: f(x)= 369.8033575119023
# differential_evolution step 167: f(x)= 369.8033575119023
# differential_evolution step 168: f(x)= 369.8033575119023
# differential_evolution step 169: f(x)= 365.49386605239664
# differential_evolution step 170: f(x)= 365.49386605239664
# differential_evolution step 171: f(x)= 365.49386605239664
# differential_evolution step 172: f(x)= 365.49386605239664
# differential_evolution step 173: f(x)= 365.49386605239664
# differential_evolution step 174: f(x)= 365.49386605239664
# differential_evolution step 175: f(x)= 365.49386605239664
# differential_evolution step 176: f(x)= 365.49386605239664
# differential_evolution step 177: f(x)= 365.49386605239664
# differential_evolution step 178: f(x)= 365.49386605239664
# differential_evolution step 179: f(x)= 365.49386605239664
# differential_evolution step 180: f(x)= 364.40542502759564
# differential_evolution step 181: f(x)= 364.40542502759564
# differential_evolution step 182: f(x)= 364.40542502759564
# differential_evolution step 183: f(x)= 364.40542502759564
# differential_evolution step 184: f(x)= 364.40542502759564
# differential_evolution step 185: f(x)= 364.40542502759564
# differential_evolution step 186: f(x)= 364.40542502759564
# differential_evolution step 187: f(x)= 364.40542502759564
# differential_evolution step 188: f(x)= 364.40542502759564
# differential_evolution step 189: f(x)= 364.40542502759564
# differential_evolution step 190: f(x)= 364.40542502759564
# differential_evolution step 191: f(x)= 364.40542502759564
# differential_evolution step 192: f(x)= 364.40542502759564
# differential_evolution step 193: f(x)= 364.40542502759564
# differential_evolution step 194: f(x)= 364.40542502759564
# differential_evolution step 195: f(x)= 362.227526199996
# differential_evolution step 196: f(x)= 362.227526199996
# differential_evolution step 197: f(x)= 362.227526199996
# differential_evolution step 198: f(x)= 361.7802110274362
# differential_evolution step 199: f(x)= 361.7802110274362
# differential_evolution step 200: f(x)= 361.7802110274362
# differential_evolution step 201: f(x)= 361.7802110274362
# differential_evolution step 202: f(x)= 361.7802110274362
# differential_evolution step 203: f(x)= 361.73641999441935
# differential_evolution step 204: f(x)= 361.73641999441935
# differential_evolution step 205: f(x)= 361.73641999441935
# differential_evolution step 206: f(x)= 361.73641999441935
# differential_evolution step 207: f(x)= 361.165476244287
# differential_evolution step 208: f(x)= 361.165476244287
# differential_evolution step 209: f(x)= 361.165476244287
# differential_evolution step 210: f(x)= 360.58839414020525
# differential_evolution step 211: f(x)= 360.58839414020525
# differential_evolution step 212: f(x)= 360.58839414020525
# differential_evolution step 213: f(x)= 360.58839414020525
# differential_evolution step 214: f(x)= 360.58839414020525
# differential_evolution step 215: f(x)= 359.71795393092935
# differential_evolution step 216: f(x)= 357.24418000109534
# differential_evolution step 217: f(x)= 357.24418000109534
# differential_evolution step 218: f(x)= 357.24418000109534
# differential_evolution step 219: f(x)= 357.24418000109534
# differential_evolution step 220: f(x)= 357.24418000109534
# differential_evolution step 221: f(x)= 357.24418000109534
# differential_evolution step 222: f(x)= 357.24418000109534
# differential_evolution step 223: f(x)= 357.24418000109534
# differential_evolution step 224: f(x)= 357.24418000109534
# differential_evolution step 225: f(x)= 357.24418000109534
# differential_evolution step 226: f(x)= 357.24418000109534
# differential_evolution step 227: f(x)= 357.24418000109534
# differential_evolution step 228: f(x)= 357.24418000109534
# differential_evolution step 229: f(x)= 357.24418000109534
# differential_evolution step 230: f(x)= 357.24418000109534
# differential_evolution step 231: f(x)= 357.24418000109534
# differential_evolution step 232: f(x)= 357.24418000109534
# differential_evolution step 233: f(x)= 357.24418000109534
# differential_evolution step 234: f(x)= 357.24418000109534
# differential_evolution step 235: f(x)= 357.24418000109534
# differential_evolution step 236: f(x)= 357.24418000109534
# differential_evolution step 237: f(x)= 357.24418000109534
# differential_evolution step 238: f(x)= 357.24418000109534
# differential_evolution step 239: f(x)= 357.24418000109534
# differential_evolution step 240: f(x)= 357.24418000109534
# differential_evolution step 241: f(x)= 357.24418000109534
# differential_evolution step 242: f(x)= 357.24418000109534
# differential_evolution step 243: f(x)= 357.24418000109534
# differential_evolution step 244: f(x)= 357.24418000109534
# differential_evolution step 245: f(x)= 357.24418000109534
# differential_evolution step 246: f(x)= 355.5094451663624
# differential_evolution step 247: f(x)= 355.5094451663624
# differential_evolution step 248: f(x)= 355.5094451663624
# differential_evolution step 249: f(x)= 355.5094451663624
# differential_evolution step 250: f(x)= 355.5094451663624
# differential_evolution step 251: f(x)= 355.5094451663624
# differential_evolution step 252: f(x)= 355.5094451663624
# differential_evolution step 253: f(x)= 355.5094451663624
# differential_evolution step 254: f(x)= 355.5094451663624
# differential_evolution step 255: f(x)= 355.5094451663624
# differential_evolution step 256: f(x)= 355.5094451663624
# differential_evolution step 257: f(x)= 355.5094451663624
# differential_evolution step 258: f(x)= 355.5094451663624
# differential_evolution step 259: f(x)= 355.5094451663624
# differential_evolution step 260: f(x)= 355.5094451663624
# differential_evolution step 261: f(x)= 355.5094451663624
# differential_evolution step 262: f(x)= 355.5094451663624
# differential_evolution step 263: f(x)= 355.5094451663624
# differential_evolution step 264: f(x)= 355.42977290513255
# differential_evolution step 265: f(x)= 355.42977290513255
# differential_evolution step 266: f(x)= 355.42977290513255
# differential_evolution step 267: f(x)= 355.24114012728
# differential_evolution step 268: f(x)= 355.24114012728
# differential_evolution step 269: f(x)= 355.24114012728
# differential_evolution step 270: f(x)= 354.2039718461342
# differential_evolution step 271: f(x)= 353.94225644020395
# differential_evolution step 272: f(x)= 353.94225644020395
# differential_evolution step 273: f(x)= 353.94225644020395
# differential_evolution step 274: f(x)= 353.94225644020395
# differential_evolution step 275: f(x)= 353.6289286233017
# differential_evolution step 276: f(x)= 353.6289286233017
# differential_evolution step 277: f(x)= 353.6289286233017
# differential_evolution step 278: f(x)= 353.6289286233017
# differential_evolution step 279: f(x)= 353.6289286233017
# differential_evolution step 280: f(x)= 353.6289286233017
# differential_evolution step 281: f(x)= 353.6289286233017
# differential_evolution step 282: f(x)= 353.6289286233017
# differential_evolution step 283: f(x)= 353.6289286233017
# differential_evolution step 284: f(x)= 353.5307792390421
# differential_evolution step 285: f(x)= 352.933804968373
# differential_evolution step 286: f(x)= 352.933804968373
# differential_evolution step 287: f(x)= 352.933804968373
# differential_evolution step 288: f(x)= 352.6158467889649
# differential_evolution step 289: f(x)= 352.6158467889649
# differential_evolution step 290: f(x)= 352.6158467889649
# differential_evolution step 291: f(x)= 352.6158467889649
# differential_evolution step 292: f(x)= 352.48812464323674
# differential_evolution step 293: f(x)= 352.48812464323674
# differential_evolution step 294: f(x)= 352.48812464323674
# differential_evolution step 295: f(x)= 352.48812464323674
# differential_evolution step 296: f(x)= 352.25341462720826
# differential_evolution step 297: f(x)= 352.25341462720826
# differential_evolution step 298: f(x)= 352.25341462720826
# differential_evolution step 299: f(x)= 352.25341462720826
# differential_evolution step 300: f(x)= 352.25341462720826
# differential_evolution step 301: f(x)= 352.0622401273518
# differential_evolution step 302: f(x)= 352.02644722679787
# differential_evolution step 303: f(x)= 352.02644722679787
# differential_evolution step 304: f(x)= 352.02644722679787
# differential_evolution step 305: f(x)= 352.02644722679787
# differential_evolution step 306: f(x)= 352.02644722679787
# differential_evolution step 307: f(x)= 352.02644722679787
# differential_evolution step 308: f(x)= 352.02644722679787
# differential_evolution step 309: f(x)= 351.87029394445904
# differential_evolution step 310: f(x)= 351.87029394445904
# differential_evolution step 311: f(x)= 351.87029394445904
# differential_evolution step 312: f(x)= 351.87029394445904
# differential_evolution step 313: f(x)= 351.87029394445904
# differential_evolution step 314: f(x)= 351.7665748056367
# differential_evolution step 315: f(x)= 351.7665748056367
# differential_evolution step 316: f(x)= 351.2107512183856
# differential_evolution step 317: f(x)= 351.2107512183856
# differential_evolution step 318: f(x)= 351.2107512183856
# differential_evolution step 319: f(x)= 351.2107512183856
# differential_evolution step 320: f(x)= 351.2107512183856
# differential_evolution step 321: f(x)= 350.96475560468764
# differential_evolution step 322: f(x)= 350.96475560468764
# differential_evolution step 323: f(x)= 350.96475560468764
# differential_evolution step 324: f(x)= 350.82472883044596
# differential_evolution step 325: f(x)= 350.82472883044596
# differential_evolution step 326: f(x)= 350.7770829683329
# differential_evolution step 327: f(x)= 350.7770829683329
# differential_evolution step 328: f(x)= 350.7770829683329
# differential_evolution step 329: f(x)= 350.7770829683329
# differential_evolution step 330: f(x)= 350.7706661526138
# differential_evolution step 331: f(x)= 350.7706661526138
# differential_evolution step 332: f(x)= 350.760817243743
# differential_evolution step 333: f(x)= 350.501411470471
# differential_evolution step 334: f(x)= 350.501411470471
# differential_evolution step 335: f(x)= 350.501411470471
# differential_evolution step 336: f(x)= 350.501411470471
# differential_evolution step 337: f(x)= 350.45994941449163
# differential_evolution step 338: f(x)= 350.45994941449163
# differential_evolution step 339: f(x)= 350.33853814493824
# differential_evolution step 340: f(x)= 350.33853814493824
# differential_evolution step 341: f(x)= 350.33853814493824
# differential_evolution step 342: f(x)= 350.33853814493824
# differential_evolution step 343: f(x)= 350.33853814493824
# differential_evolution step 344: f(x)= 350.33853814493824
# differential_evolution step 345: f(x)= 350.33853814493824
# differential_evolution step 346: f(x)= 350.33853814493824
# differential_evolution step 347: f(x)= 350.33853814493824
# differential_evolution step 348: f(x)= 350.20586633603847
# differential_evolution step 349: f(x)= 350.20586633603847
# differential_evolution step 350: f(x)= 350.153345852541
# differential_evolution step 351: f(x)= 350.153345852541
# differential_evolution step 352: f(x)= 350.153345852541
# differential_evolution step 353: f(x)= 350.153345852541
# differential_evolution step 354: f(x)= 350.153345852541
# differential_evolution step 355: f(x)= 350.153345852541
# differential_evolution step 356: f(x)= 350.153345852541
# differential_evolution step 357: f(x)= 350.0285165226633
# differential_evolution step 358: f(x)= 350.0285165226633
# differential_evolution step 359: f(x)= 350.0285165226633
# differential_evolution step 360: f(x)= 350.0285165226633
# differential_evolution step 361: f(x)= 349.9393286120946
# differential_evolution step 362: f(x)= 349.93510394584627
# differential_evolution step 363: f(x)= 349.93510394584627
# differential_evolution step 364: f(x)= 349.93510394584627
# differential_evolution step 365: f(x)= 349.72543871522316
# differential_evolution step 366: f(x)= 349.72543871522316
# differential_evolution step 367: f(x)= 349.72543871522316
# differential_evolution step 368: f(x)= 349.72543871522316
# differential_evolution step 369: f(x)= 349.72543871522316
# differential_evolution step 370: f(x)= 349.72543871522316
# differential_evolution step 371: f(x)= 349.72543871522316
# differential_evolution step 372: f(x)= 349.72543871522316
# differential_evolution step 373: f(x)= 349.72543871522316
# differential_evolution step 374: f(x)= 349.72543871522316
# differential_evolution step 375: f(x)= 349.72543871522316
# differential_evolution step 376: f(x)= 349.72543871522316
# differential_evolution step 377: f(x)= 349.72543871522316
# differential_evolution step 378: f(x)= 349.72543871522316
# differential_evolution step 379: f(x)= 349.72543871522316
# differential_evolution step 380: f(x)= 349.72543871522316
# differential_evolution step 381: f(x)= 349.71118656321585
# differential_evolution step 382: f(x)= 349.71118656321585
# differential_evolution step 383: f(x)= 349.71118656321585
# differential_evolution step 384: f(x)= 349.71118656321585
# differential_evolution step 385: f(x)= 349.71118656321585
# differential_evolution step 386: f(x)= 349.71118656321585
# differential_evolution step 387: f(x)= 349.71118656321585
# differential_evolution step 388: f(x)= 349.71118656321585
# differential_evolution step 389: f(x)= 349.71118656321585
# differential_evolution step 390: f(x)= 349.71118656321585
# differential_evolution step 391: f(x)= 349.71118656321585
# differential_evolution step 392: f(x)= 349.70282616545705
# differential_evolution step 393: f(x)= 349.70282616545705
# differential_evolution step 394: f(x)= 349.70282616545705
# differential_evolution step 395: f(x)= 349.70282616545705
# differential_evolution step 396: f(x)= 349.70282616545705
# differential_evolution step 397: f(x)= 349.70282616545705
# differential_evolution step 398: f(x)= 349.6811036130074
# differential_evolution step 399: f(x)= 349.6811036130074
# differential_evolution step 400: f(x)= 349.6811036130074
# differential_evolution step 401: f(x)= 349.6765346679458
# differential_evolution step 402: f(x)= 349.6765346679458
# differential_evolution step 403: f(x)= 349.6765346679458
# differential_evolution step 404: f(x)= 349.6765346679458
# differential_evolution step 405: f(x)= 349.6765346679458
# differential_evolution step 406: f(x)= 349.6765346679458
# differential_evolution step 407: f(x)= 349.6765346679458
# differential_evolution step 408: f(x)= 349.6765346679458
# differential_evolution step 409: f(x)= 349.6390829080887
# differential_evolution step 410: f(x)= 349.6390829080887
# differential_evolution step 411: f(x)= 349.6390829080887
# differential_evolution step 412: f(x)= 349.6315865602791
# differential_evolution step 413: f(x)= 349.6315865602791
# differential_evolution step 414: f(x)= 349.6315865602791
# differential_evolution step 415: f(x)= 349.6315865602791
# differential_evolution step 416: f(x)= 349.6315865602791
# differential_evolution step 417: f(x)= 349.6289152295808
# differential_evolution step 418: f(x)= 349.6039395459194
# differential_evolution step 419: f(x)= 349.6039395459194
# differential_evolution step 420: f(x)= 349.6039395459194
# differential_evolution step 421: f(x)= 349.6039395459194
# differential_evolution step 422: f(x)= 349.6039395459194
# differential_evolution step 423: f(x)= 349.6039395459194
# differential_evolution step 424: f(x)= 349.6039395459194
# differential_evolution step 425: f(x)= 349.6039395459194
# differential_evolution step 426: f(x)= 349.6039395459194
# differential_evolution step 427: f(x)= 349.6039395459194
# differential_evolution step 428: f(x)= 349.6039395459194
# differential_evolution step 429: f(x)= 349.6039395459194
# differential_evolution step 430: f(x)= 349.6039395459194
# differential_evolution step 431: f(x)= 349.6039395459194
# differential_evolution step 432: f(x)= 349.6039395459194
# differential_evolution step 433: f(x)= 349.6039395459194
# differential_evolution step 434: f(x)= 349.6024488215641
# differential_evolution step 435: f(x)= 349.6024488215641
# differential_evolution step 436: f(x)= 349.60130232457686
# differential_evolution step 437: f(x)= 349.60130232457686
# differential_evolution step 438: f(x)= 349.60130232457686
# differential_evolution step 439: f(x)= 349.60130232457686
# differential_evolution step 440: f(x)= 349.60130232457686
# differential_evolution step 441: f(x)= 349.60130232457686
# differential_evolution step 442: f(x)= 349.60130232457686
# differential_evolution step 443: f(x)= 349.59412613284064
# differential_evolution step 444: f(x)= 349.59412613284064
# differential_evolution step 445: f(x)= 349.59412613284064
# differential_evolution step 446: f(x)= 349.59412613284064
# differential_evolution step 447: f(x)= 349.59412613284064
# differential_evolution step 448: f(x)= 349.59412613284064
# differential_evolution step 449: f(x)= 349.59412613284064
# differential_evolution step 450: f(x)= 349.59412613284064
# differential_evolution step 451: f(x)= 349.59412613284064
# differential_evolution step 452: f(x)= 349.59412613284064
# differential_evolution step 453: f(x)= 349.59412613284064
# differential_evolution step 454: f(x)= 349.5938807039551
# differential_evolution step 455: f(x)= 349.5938807039551
# differential_evolution step 456: f(x)= 349.5938807039551
# differential_evolution step 457: f(x)= 349.5938807039551
# differential_evolution step 458: f(x)= 349.5938807039551
# differential_evolution step 459: f(x)= 349.58835560255716
# differential_evolution step 460: f(x)= 349.58835560255716
# differential_evolution step 461: f(x)= 349.58264936079325
# differential_evolution step 462: f(x)= 349.58264936079325
# differential_evolution step 463: f(x)= 349.58264936079325
# differential_evolution step 464: f(x)= 349.58264936079325
# differential_evolution step 465: f(x)= 349.58264936079325
# differential_evolution step 466: f(x)= 349.58264936079325
# differential_evolution step 467: f(x)= 349.58264936079325
# differential_evolution step 468: f(x)= 349.58264936079325
# differential_evolution step 469: f(x)= 349.58264936079325
# differential_evolution step 470: f(x)= 349.58015450580416
# differential_evolution step 471: f(x)= 349.58015450580416
# differential_evolution step 472: f(x)= 349.58015450580416
# differential_evolution step 473: f(x)= 349.58015450580416
# differential_evolution step 474: f(x)= 349.58015450580416
# differential_evolution step 475: f(x)= 349.58015450580416
# differential_evolution step 476: f(x)= 349.58015450580416
# differential_evolution step 477: f(x)= 349.58015450580416
# differential_evolution step 478: f(x)= 349.57455681403144
# differential_evolution step 479: f(x)= 349.57455681403144
# differential_evolution step 480: f(x)= 349.57455681403144
# differential_evolution step 481: f(x)= 349.57455681403144
# differential_evolution step 482: f(x)= 349.57455681403144
# differential_evolution step 483: f(x)= 349.57455681403144
# differential_evolution step 484: f(x)= 349.57455681403144
# differential_evolution step 485: f(x)= 349.57352143190326
# differential_evolution step 486: f(x)= 349.57352143190326
# differential_evolution step 487: f(x)= 349.57352143190326
# differential_evolution step 488: f(x)= 349.57352143190326
# differential_evolution step 489: f(x)= 349.57352143190326
# differential_evolution step 490: f(x)= 349.57352143190326
# differential_evolution step 491: f(x)= 349.57352143190326
# differential_evolution step 492: f(x)= 349.57352143190326
# differential_evolution step 493: f(x)= 349.57352143190326
# differential_evolution step 494: f(x)= 349.57352143190326
# differential_evolution step 495: f(x)= 349.57352143190326
# differential_evolution step 496: f(x)= 349.57352143190326
# differential_evolution step 497: f(x)= 349.57352143190326
# differential_evolution step 498: f(x)= 349.57352143190326
# differential_evolution step 499: f(x)= 349.57352143190326
# differential_evolution step 500: f(x)= 349.5695228305052
# differential_evolution step 501: f(x)= 349.5695228305052
# differential_evolution step 502: f(x)= 349.5695228305052
# differential_evolution step 503: f(x)= 349.5695228305052
# differential_evolution step 504: f(x)= 349.5695228305052
# differential_evolution step 505: f(x)= 349.5695228305052
# differential_evolution step 506: f(x)= 349.5695228305052
# differential_evolution step 507: f(x)= 349.5695228305052
# differential_evolution step 508: f(x)= 349.5695228305052
# differential_evolution step 509: f(x)= 349.5695228305052
# differential_evolution step 510: f(x)= 349.5695228305052
# differential_evolution step 511: f(x)= 349.5695228305052
# differential_evolution step 512: f(x)= 349.5695228305052
# differential_evolution step 513: f(x)= 349.5695228305052
# differential_evolution step 514: f(x)= 349.5695228305052
# differential_evolution step 515: f(x)= 349.5695228305052
# differential_evolution step 516: f(x)= 349.5695228305052
# differential_evolution step 517: f(x)= 349.5695228305052
# differential_evolution step 518: f(x)= 349.5695228305052
# differential_evolution step 519: f(x)= 349.5695228305052
# differential_evolution step 520: f(x)= 349.5695228305052
# differential_evolution step 521: f(x)= 349.5694729440833
# differential_evolution step 522: f(x)= 349.5694729440833
# differential_evolution step 523: f(x)= 349.5694729440833
# differential_evolution step 524: f(x)= 349.5694729440833
# differential_evolution step 525: f(x)= 349.5694729440833
# differential_evolution step 526: f(x)= 349.5694729440833
# differential_evolution step 527: f(x)= 349.5694729440833
# differential_evolution step 528: f(x)= 349.56909167045615
# differential_evolution step 529: f(x)= 349.56909167045615
# differential_evolution step 530: f(x)= 349.56909167045615
# differential_evolution step 531: f(x)= 349.56909167045615
# differential_evolution step 532: f(x)= 349.56909167045615
# differential_evolution step 533: f(x)= 349.56909167045615
# differential_evolution step 534: f(x)= 349.56909167045615
# differential_evolution step 535: f(x)= 349.56909167045615
# differential_evolution step 536: f(x)= 349.56909167045615
# differential_evolution step 537: f(x)= 349.56909167045615
# differential_evolution step 538: f(x)= 349.56909167045615
# differential_evolution step 539: f(x)= 349.56909167045615
# differential_evolution step 540: f(x)= 349.56909167045615
# differential_evolution step 541: f(x)= 349.56909167045615
# differential_evolution step 542: f(x)= 349.567297565483
# differential_evolution step 543: f(x)= 349.567297565483
# differential_evolution step 544: f(x)= 349.567297565483
# differential_evolution step 545: f(x)= 349.567297565483
# differential_evolution step 546: f(x)= 349.56711393596186
# differential_evolution step 547: f(x)= 349.56711393596186
# differential_evolution step 548: f(x)= 349.56711393596186
# differential_evolution step 549: f(x)= 349.56711393596186
# differential_evolution step 550: f(x)= 349.56711393596186
# differential_evolution step 551: f(x)= 349.56670769094825
# differential_evolution step 552: f(x)= 349.56670769094825
# differential_evolution step 553: f(x)= 349.56670769094825
# differential_evolution step 554: f(x)= 349.56670769094825
# differential_evolution step 555: f(x)= 349.56670769094825
# differential_evolution step 556: f(x)= 349.56670769094825
# differential_evolution step 557: f(x)= 349.56670769094825
# differential_evolution step 558: f(x)= 349.56670769094825
# differential_evolution step 559: f(x)= 349.56670769094825
# differential_evolution step 560: f(x)= 349.56670769094825
# differential_evolution step 561: f(x)= 349.56670769094825
# differential_evolution step 562: f(x)= 349.56670769094825
# differential_evolution step 563: f(x)= 349.56670769094825
# differential_evolution step 564: f(x)= 349.56670769094825
# differential_evolution step 565: f(x)= 349.56670769094825
# differential_evolution step 566: f(x)= 349.56670769094825
# differential_evolution step 567: f(x)= 349.56670769094825
# differential_evolution step 568: f(x)= 349.56670769094825
# differential_evolution step 569: f(x)= 349.56670769094825
# differential_evolution step 570: f(x)= 349.56670769094825
# differential_evolution step 571: f(x)= 349.56670769094825
# differential_evolution step 572: f(x)= 349.56670769094825
# differential_evolution step 573: f(x)= 349.56670769094825
# differential_evolution step 574: f(x)= 349.5661761727864
# differential_evolution step 575: f(x)= 349.5661761727864
# differential_evolution step 576: f(x)= 349.5655654651395
# differential_evolution step 577: f(x)= 349.5655654651395
# differential_evolution step 578: f(x)= 349.5655654651395
# differential_evolution step 579: f(x)= 349.5655654651395
# differential_evolution step 580: f(x)= 349.5655654651395
# differential_evolution step 581: f(x)= 349.5655654651395
# differential_evolution step 582: f(x)= 349.5655654651395
# differential_evolution step 583: f(x)= 349.5655654651395
# differential_evolution step 584: f(x)= 349.5655654651395
# differential_evolution step 585: f(x)= 349.5655654651395
# differential_evolution step 586: f(x)= 349.5655654651395
# differential_evolution step 587: f(x)= 349.5655654651395
# differential_evolution step 588: f(x)= 349.5655654651395
# differential_evolution step 589: f(x)= 349.5655654651395
# differential_evolution step 590: f(x)= 349.5655654651395
# differential_evolution step 591: f(x)= 349.5655654651395
# differential_evolution step 592: f(x)= 349.5655654651395
# differential_evolution step 593: f(x)= 349.5655654651395
# differential_evolution step 594: f(x)= 349.5655654651395
# differential_evolution step 595: f(x)= 349.5655654651395
# differential_evolution step 596: f(x)= 349.5655654651395
# differential_evolution step 597: f(x)= 349.5655654651395
# differential_evolution step 598: f(x)= 349.5655654651395
# differential_evolution step 599: f(x)= 349.5655654651395
# differential_evolution step 600: f(x)= 349.5655654651395
# differential_evolution step 601: f(x)= 349.5655096909327
# differential_evolution step 602: f(x)= 349.5655096909327
# differential_evolution step 603: f(x)= 349.5655096909327
# differential_evolution step 604: f(x)= 349.5655096909327
# differential_evolution step 605: f(x)= 349.5655096909327
# differential_evolution step 606: f(x)= 349.5655096909327
# differential_evolution step 607: f(x)= 349.5655096909327
# differential_evolution step 608: f(x)= 349.5655096909327
# differential_evolution step 609: f(x)= 349.5655096909327
# differential_evolution step 610: f(x)= 349.5655096909327
# differential_evolution step 611: f(x)= 349.5655096909327
# differential_evolution step 612: f(x)= 349.5652182928001
# differential_evolution step 613: f(x)= 349.5652182928001
# differential_evolution step 614: f(x)= 349.5650545325511
# differential_evolution step 615: f(x)= 349.5650545325511
# differential_evolution step 616: f(x)= 349.5650545325511
# differential_evolution step 617: f(x)= 349.5650545325511
# differential_evolution step 618: f(x)= 349.5650545325511
# differential_evolution step 619: f(x)= 349.5650545325511
# differential_evolution step 620: f(x)= 349.5650545325511
# differential_evolution step 621: f(x)= 349.5650545325511
# differential_evolution step 622: f(x)= 349.565046827177
# differential_evolution step 623: f(x)= 349.565046827177
# differential_evolution step 624: f(x)= 349.565046827177
# differential_evolution step 625: f(x)= 349.565046827177
# differential_evolution step 626: f(x)= 349.565046827177
# differential_evolution step 627: f(x)= 349.565046827177
# differential_evolution step 628: f(x)= 349.565046827177
# differential_evolution step 629: f(x)= 349.565046827177
# differential_evolution step 630: f(x)= 349.565016066787
# differential_evolution step 631: f(x)= 349.565016066787
# differential_evolution step 632: f(x)= 349.565016066787
# differential_evolution step 633: f(x)= 349.565016066787
# differential_evolution step 634: f(x)= 349.565016066787
# differential_evolution step 635: f(x)= 349.565016066787
# differential_evolution step 636: f(x)= 349.565016066787
# differential_evolution step 637: f(x)= 349.565016066787
# differential_evolution step 638: f(x)= 349.565016066787
# differential_evolution step 639: f(x)= 349.565016066787
# differential_evolution step 640: f(x)= 349.56491471150355
# differential_evolution step 641: f(x)= 349.56491471150355
# differential_evolution step 642: f(x)= 349.56491471150355
# differential_evolution step 643: f(x)= 349.56491471150355
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=100.0000, r_e=2.8328, n=0.3089, x_0=40.6116
# Sérsic 2: I_e=10.3177, r_e=9.2275, n=1.0185, x_0=48.3869
# Sérsic 3: I_e=8.9759, r_e=3.1252, n=1.4527, x_0=59.0912
# Chi quadro minimo: 349.5647949424388
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Sérsic 1: I_e=100.0000, r_e=2.8328, n=0.3089, x_0=40.6116
# Sérsic 2: I_e=10.3177, r_e=9.2275, n=1.0185, x_0=48.3869
# Sérsic 3: I_e=8.9759, r_e=3.1252, n=1.4527, x_0=59.0912
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=77.3927, r_e=3.1547, n=0.5359, x_0=40.7216
# Sérsic 2: I_e=9.8531, r_e=7.4071, n=1.0130, x_0=48.8178
# Sérsic 3: I_e=6.8969, r_e=4.5700, n=1.5626, x_0=59.1178
# [7.57377964 0.17460583 0.07952949 0.20111763 3.12566207 1.3448299
#  0.22413213 0.60514519 3.12832399 1.27500769 0.49120233 0.15790212]
# 13.025120876489531

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA
seeing_i = 3.174
sigma_i = seeing_i/ 2.35

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigma_i)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 87309.48721695768
# differential_evolution step 2: f(x)= 60096.27233102461
# differential_evolution step 3: f(x)= 60096.27233102461
# differential_evolution step 4: f(x)= 60096.27233102461
# differential_evolution step 5: f(x)= 48834.017750260944
# differential_evolution step 6: f(x)= 44210.222828427635
# differential_evolution step 7: f(x)= 44210.222828427635
# differential_evolution step 8: f(x)= 44210.222828427635
# differential_evolution step 9: f(x)= 38780.02566825441
# differential_evolution step 10: f(x)= 26242.43380235343
# differential_evolution step 11: f(x)= 26242.43380235343
# differential_evolution step 12: f(x)= 26242.43380235343
# differential_evolution step 13: f(x)= 26242.43380235343
# differential_evolution step 14: f(x)= 26242.43380235343
# differential_evolution step 15: f(x)= 26242.43380235343
# differential_evolution step 16: f(x)= 19960.587494076277
# differential_evolution step 17: f(x)= 19960.587494076277
# differential_evolution step 18: f(x)= 19960.587494076277
# differential_evolution step 19: f(x)= 19469.243463561095
# differential_evolution step 20: f(x)= 18466.072297285686
# differential_evolution step 21: f(x)= 18466.072297285686
# differential_evolution step 22: f(x)= 18466.072297285686
# differential_evolution step 23: f(x)= 17840.453455167855
# differential_evolution step 24: f(x)= 17840.453455167855
# differential_evolution step 25: f(x)= 17840.453455167855
# differential_evolution step 26: f(x)= 17840.453455167855
# differential_evolution step 27: f(x)= 15987.914068683243
# differential_evolution step 28: f(x)= 15987.914068683243
# differential_evolution step 29: f(x)= 15987.914068683243
# differential_evolution step 30: f(x)= 15987.914068683243
# differential_evolution step 31: f(x)= 15957.056983109365
# differential_evolution step 32: f(x)= 15957.056983109365
# differential_evolution step 33: f(x)= 15957.056983109365
# differential_evolution step 34: f(x)= 15957.056983109365
# differential_evolution step 35: f(x)= 14539.929655659618
# differential_evolution step 36: f(x)= 10648.061335034938
# differential_evolution step 37: f(x)= 10648.061335034938
# differential_evolution step 38: f(x)= 10648.061335034938
# differential_evolution step 39: f(x)= 10648.061335034938
# differential_evolution step 40: f(x)= 9710.04170848461
# differential_evolution step 41: f(x)= 9710.04170848461
# differential_evolution step 42: f(x)= 9710.04170848461
# differential_evolution step 43: f(x)= 9710.04170848461
# differential_evolution step 44: f(x)= 9710.04170848461
# differential_evolution step 45: f(x)= 9710.04170848461
# differential_evolution step 46: f(x)= 9710.04170848461
# differential_evolution step 47: f(x)= 9710.04170848461
# differential_evolution step 48: f(x)= 9710.04170848461
# differential_evolution step 49: f(x)= 9710.04170848461
# differential_evolution step 50: f(x)= 9710.04170848461
# differential_evolution step 51: f(x)= 8849.693766856017
# differential_evolution step 52: f(x)= 8849.693766856017
# differential_evolution step 53: f(x)= 8849.693766856017
# differential_evolution step 54: f(x)= 8849.693766856017
# differential_evolution step 55: f(x)= 8849.693766856017
# differential_evolution step 56: f(x)= 8849.693766856017
# differential_evolution step 57: f(x)= 8849.693766856017
# differential_evolution step 58: f(x)= 8724.57823602068
# differential_evolution step 59: f(x)= 8724.57823602068
# differential_evolution step 60: f(x)= 8724.57823602068
# differential_evolution step 61: f(x)= 8724.57823602068
# differential_evolution step 62: f(x)= 8015.320872131003
# differential_evolution step 63: f(x)= 8015.320872131003
# differential_evolution step 64: f(x)= 8015.320872131003
# differential_evolution step 65: f(x)= 8015.320872131003
# differential_evolution step 66: f(x)= 8015.320872131003
# differential_evolution step 67: f(x)= 7746.587407218879
# differential_evolution step 68: f(x)= 7481.4226939081655
# differential_evolution step 69: f(x)= 7481.4226939081655
# differential_evolution step 70: f(x)= 7481.4226939081655
# differential_evolution step 71: f(x)= 6897.397823122853
# differential_evolution step 72: f(x)= 6897.397823122853
# differential_evolution step 73: f(x)= 6897.397823122853
# differential_evolution step 74: f(x)= 6897.397823122853
# differential_evolution step 75: f(x)= 6897.397823122853
# differential_evolution step 76: f(x)= 6814.987290759546
# differential_evolution step 77: f(x)= 6098.980856451036
# differential_evolution step 78: f(x)= 6098.980856451036
# differential_evolution step 79: f(x)= 6098.980856451036
# differential_evolution step 80: f(x)= 6098.980856451036
# differential_evolution step 81: f(x)= 6098.980856451036
# differential_evolution step 82: f(x)= 6098.980856451036
# differential_evolution step 83: f(x)= 6098.980856451036
# differential_evolution step 84: f(x)= 6098.980856451036
# differential_evolution step 85: f(x)= 6098.980856451036
# differential_evolution step 86: f(x)= 6098.980856451036
# differential_evolution step 87: f(x)= 6098.980856451036
# differential_evolution step 88: f(x)= 5292.091646850671
# differential_evolution step 89: f(x)= 5292.091646850671
# differential_evolution step 90: f(x)= 5292.091646850671
# differential_evolution step 91: f(x)= 5292.091646850671
# differential_evolution step 92: f(x)= 5292.091646850671
# differential_evolution step 93: f(x)= 5292.091646850671
# differential_evolution step 94: f(x)= 5258.3222812775975
# differential_evolution step 95: f(x)= 5258.3222812775975
# differential_evolution step 96: f(x)= 5208.310709501218
# differential_evolution step 97: f(x)= 4308.2423687124365
# differential_evolution step 98: f(x)= 4308.2423687124365
# differential_evolution step 99: f(x)= 4308.2423687124365
# differential_evolution step 100: f(x)= 4308.2423687124365
# differential_evolution step 101: f(x)= 4308.2423687124365
# differential_evolution step 102: f(x)= 4308.2423687124365
# differential_evolution step 103: f(x)= 4115.198291852456
# differential_evolution step 104: f(x)= 4115.198291852456
# differential_evolution step 105: f(x)= 4115.198291852456
# differential_evolution step 106: f(x)= 4115.198291852456
# differential_evolution step 107: f(x)= 4115.198291852456
# differential_evolution step 108: f(x)= 4115.198291852456
# differential_evolution step 109: f(x)= 4115.198291852456
# differential_evolution step 110: f(x)= 4115.198291852456
# differential_evolution step 111: f(x)= 4115.198291852456
# differential_evolution step 112: f(x)= 4115.198291852456
# differential_evolution step 113: f(x)= 4115.198291852456
# differential_evolution step 114: f(x)= 4115.198291852456
# differential_evolution step 115: f(x)= 4115.198291852456
# differential_evolution step 116: f(x)= 4115.198291852456
# differential_evolution step 117: f(x)= 4115.198291852456
# differential_evolution step 118: f(x)= 4115.198291852456
# differential_evolution step 119: f(x)= 4115.198291852456
# differential_evolution step 120: f(x)= 3932.8760051921877
# differential_evolution step 121: f(x)= 3438.3891909839044
# differential_evolution step 122: f(x)= 3438.3891909839044
# differential_evolution step 123: f(x)= 3438.3891909839044
# differential_evolution step 124: f(x)= 3438.3891909839044
# differential_evolution step 125: f(x)= 3438.3891909839044
# differential_evolution step 126: f(x)= 3438.3891909839044
# differential_evolution step 127: f(x)= 3438.3891909839044
# differential_evolution step 128: f(x)= 3438.3891909839044
# differential_evolution step 129: f(x)= 3438.3891909839044
# differential_evolution step 130: f(x)= 3307.9016695996984
# differential_evolution step 131: f(x)= 3307.9016695996984
# differential_evolution step 132: f(x)= 3232.8894064802935
# differential_evolution step 133: f(x)= 3232.8894064802935
# differential_evolution step 134: f(x)= 3232.8894064802935
# differential_evolution step 135: f(x)= 3232.8894064802935
# differential_evolution step 136: f(x)= 3232.8894064802935
# differential_evolution step 137: f(x)= 3232.8894064802935
# differential_evolution step 138: f(x)= 3232.8894064802935
# differential_evolution step 139: f(x)= 3232.8894064802935
# differential_evolution step 140: f(x)= 3165.117107642329
# differential_evolution step 141: f(x)= 3165.117107642329
# differential_evolution step 142: f(x)= 3165.117107642329
# differential_evolution step 143: f(x)= 3165.117107642329
# differential_evolution step 144: f(x)= 3165.117107642329
# differential_evolution step 145: f(x)= 3165.117107642329
# differential_evolution step 146: f(x)= 3165.117107642329
# differential_evolution step 147: f(x)= 3133.789390368153
# differential_evolution step 148: f(x)= 3133.789390368153
# differential_evolution step 149: f(x)= 3133.789390368153
# differential_evolution step 150: f(x)= 3133.789390368153
# differential_evolution step 151: f(x)= 3129.1659385938806
# differential_evolution step 152: f(x)= 3057.199382253513
# differential_evolution step 153: f(x)= 3057.199382253513
# differential_evolution step 154: f(x)= 3057.199382253513
# differential_evolution step 155: f(x)= 3057.199382253513
# differential_evolution step 156: f(x)= 3057.199382253513
# differential_evolution step 157: f(x)= 3057.199382253513
# differential_evolution step 158: f(x)= 3057.199382253513
# differential_evolution step 159: f(x)= 3057.199382253513
# differential_evolution step 160: f(x)= 3057.199382253513
# differential_evolution step 161: f(x)= 3057.199382253513
# differential_evolution step 162: f(x)= 3057.199382253513
# differential_evolution step 163: f(x)= 3057.199382253513
# differential_evolution step 164: f(x)= 3025.913363237792
# differential_evolution step 165: f(x)= 3025.913363237792
# differential_evolution step 166: f(x)= 3025.913363237792
# differential_evolution step 167: f(x)= 3025.913363237792
# differential_evolution step 168: f(x)= 3025.913363237792
# differential_evolution step 169: f(x)= 3025.913363237792
# differential_evolution step 170: f(x)= 3023.486648169572
# differential_evolution step 171: f(x)= 3023.486648169572
# differential_evolution step 172: f(x)= 3023.486648169572
# differential_evolution step 173: f(x)= 3023.486648169572
# differential_evolution step 174: f(x)= 3023.486648169572
# differential_evolution step 175: f(x)= 3019.261015276946
# differential_evolution step 176: f(x)= 3019.261015276946
# differential_evolution step 177: f(x)= 3019.261015276946
# differential_evolution step 178: f(x)= 3019.261015276946
# differential_evolution step 179: f(x)= 3019.261015276946
# differential_evolution step 180: f(x)= 3019.261015276946
# differential_evolution step 181: f(x)= 2982.2365222068274
# differential_evolution step 182: f(x)= 2982.2365222068274
# differential_evolution step 183: f(x)= 2982.2365222068274
# differential_evolution step 184: f(x)= 2982.2365222068274
# differential_evolution step 185: f(x)= 2962.557656331528
# differential_evolution step 186: f(x)= 2962.557656331528
# differential_evolution step 187: f(x)= 2962.557656331528
# differential_evolution step 188: f(x)= 2962.557656331528
# differential_evolution step 189: f(x)= 2962.557656331528
# differential_evolution step 190: f(x)= 2951.792432489106
# differential_evolution step 191: f(x)= 2951.792432489106
# differential_evolution step 192: f(x)= 2930.0649580097365
# differential_evolution step 193: f(x)= 2930.0649580097365
# differential_evolution step 194: f(x)= 2930.0649580097365
# differential_evolution step 195: f(x)= 2930.0649580097365
# differential_evolution step 196: f(x)= 2930.0649580097365
# differential_evolution step 197: f(x)= 2930.0649580097365
# differential_evolution step 198: f(x)= 2924.76975054816
# differential_evolution step 199: f(x)= 2924.76975054816
# differential_evolution step 200: f(x)= 2924.76975054816
# differential_evolution step 201: f(x)= 2924.76975054816
# differential_evolution step 202: f(x)= 2906.3564030673524
# differential_evolution step 203: f(x)= 2906.3564030673524
# differential_evolution step 204: f(x)= 2906.3564030673524
# differential_evolution step 205: f(x)= 2906.3564030673524
# differential_evolution step 206: f(x)= 2906.3564030673524
# differential_evolution step 207: f(x)= 2906.3564030673524
# differential_evolution step 208: f(x)= 2906.3564030673524
# differential_evolution step 209: f(x)= 2905.0026362603776
# differential_evolution step 210: f(x)= 2901.855372407516
# differential_evolution step 211: f(x)= 2898.385931498991
# differential_evolution step 212: f(x)= 2898.385931498991
# differential_evolution step 213: f(x)= 2898.385931498991
# differential_evolution step 214: f(x)= 2893.2656680369387
# differential_evolution step 215: f(x)= 2885.708394595681
# differential_evolution step 216: f(x)= 2885.708394595681
# differential_evolution step 217: f(x)= 2885.0457575430523
# differential_evolution step 218: f(x)= 2885.0457575430523
# differential_evolution step 219: f(x)= 2876.4337515093825
# differential_evolution step 220: f(x)= 2875.9852384507376
# differential_evolution step 221: f(x)= 2875.9852384507376
# differential_evolution step 222: f(x)= 2875.9852384507376
# differential_evolution step 223: f(x)= 2875.9852384507376
# differential_evolution step 224: f(x)= 2875.9852384507376
# differential_evolution step 225: f(x)= 2875.9852384507376
# differential_evolution step 226: f(x)= 2875.9852384507376
# differential_evolution step 227: f(x)= 2855.3535716651513
# differential_evolution step 228: f(x)= 2855.3535716651513
# differential_evolution step 229: f(x)= 2855.3535716651513
# differential_evolution step 230: f(x)= 2855.3535716651513
# differential_evolution step 231: f(x)= 2855.3535716651513
# differential_evolution step 232: f(x)= 2855.3535716651513
# differential_evolution step 233: f(x)= 2855.3535716651513
# differential_evolution step 234: f(x)= 2855.3535716651513
# differential_evolution step 235: f(x)= 2855.3535716651513
# differential_evolution step 236: f(x)= 2855.3535716651513
# differential_evolution step 237: f(x)= 2855.3535716651513
# differential_evolution step 238: f(x)= 2855.3535716651513
# differential_evolution step 239: f(x)= 2855.3535716651513
# differential_evolution step 240: f(x)= 2855.3535716651513
# differential_evolution step 241: f(x)= 2851.6390840443364
# differential_evolution step 242: f(x)= 2851.6390840443364
# differential_evolution step 243: f(x)= 2851.6390840443364
# differential_evolution step 244: f(x)= 2851.6390840443364
# differential_evolution step 245: f(x)= 2851.6390840443364
# differential_evolution step 246: f(x)= 2851.6390840443364
# differential_evolution step 247: f(x)= 2851.6390840443364
# differential_evolution step 248: f(x)= 2851.6390840443364
# differential_evolution step 249: f(x)= 2851.6390840443364
# differential_evolution step 250: f(x)= 2851.6390840443364
# differential_evolution step 251: f(x)= 2851.6390840443364
# differential_evolution step 252: f(x)= 2851.6390840443364
# differential_evolution step 253: f(x)= 2851.6390840443364
# differential_evolution step 254: f(x)= 2851.6390840443364
# differential_evolution step 255: f(x)= 2851.6390840443364
# differential_evolution step 256: f(x)= 2845.068234475854
# differential_evolution step 257: f(x)= 2845.068234475854
# differential_evolution step 258: f(x)= 2845.068234475854
# differential_evolution step 259: f(x)= 2845.068234475854
# differential_evolution step 260: f(x)= 2845.068234475854
# differential_evolution step 261: f(x)= 2845.068234475854
# differential_evolution step 262: f(x)= 2845.068234475854
# differential_evolution step 263: f(x)= 2845.068234475854
# differential_evolution step 264: f(x)= 2845.068234475854
# differential_evolution step 265: f(x)= 2845.068234475854
# differential_evolution step 266: f(x)= 2845.068234475854
# differential_evolution step 267: f(x)= 2845.068234475854
# differential_evolution step 268: f(x)= 2845.068234475854
# differential_evolution step 269: f(x)= 2845.068234475854
# differential_evolution step 270: f(x)= 2842.972135689435
# differential_evolution step 271: f(x)= 2842.972135689435
# differential_evolution step 272: f(x)= 2842.972135689435
# differential_evolution step 273: f(x)= 2842.972135689435
# differential_evolution step 274: f(x)= 2841.959916048648
# differential_evolution step 275: f(x)= 2841.959916048648
# differential_evolution step 276: f(x)= 2841.959916048648
# differential_evolution step 277: f(x)= 2841.959916048648
# differential_evolution step 278: f(x)= 2841.959916048648
# differential_evolution step 279: f(x)= 2841.959916048648
# differential_evolution step 280: f(x)= 2841.670510653939
# differential_evolution step 281: f(x)= 2841.670510653939
# differential_evolution step 282: f(x)= 2838.370079139278
# differential_evolution step 283: f(x)= 2838.370079139278
# differential_evolution step 284: f(x)= 2838.370079139278
# differential_evolution step 285: f(x)= 2838.370079139278
# differential_evolution step 286: f(x)= 2838.370079139278
# differential_evolution step 287: f(x)= 2838.370079139278
# differential_evolution step 288: f(x)= 2838.370079139278
# differential_evolution step 289: f(x)= 2838.370079139278
# differential_evolution step 290: f(x)= 2838.370079139278
# differential_evolution step 291: f(x)= 2836.1623936454616
# differential_evolution step 292: f(x)= 2836.1623936454616
# differential_evolution step 293: f(x)= 2836.1623936454616
# differential_evolution step 294: f(x)= 2836.1623936454616
# differential_evolution step 295: f(x)= 2836.1623936454616
# differential_evolution step 296: f(x)= 2836.1623936454616
# differential_evolution step 297: f(x)= 2836.1623936454616
# differential_evolution step 298: f(x)= 2836.1623936454616
# differential_evolution step 299: f(x)= 2835.771358553276
# differential_evolution step 300: f(x)= 2835.771358553276
# differential_evolution step 301: f(x)= 2835.771358553276
# differential_evolution step 302: f(x)= 2835.771358553276
# differential_evolution step 303: f(x)= 2835.771358553276
# differential_evolution step 304: f(x)= 2835.771358553276
# differential_evolution step 305: f(x)= 2835.771358553276
# differential_evolution step 306: f(x)= 2835.771358553276
# differential_evolution step 307: f(x)= 2835.771358553276
# differential_evolution step 308: f(x)= 2835.771358553276
# differential_evolution step 309: f(x)= 2834.1533212039526
# differential_evolution step 310: f(x)= 2834.1533212039526
# differential_evolution step 311: f(x)= 2833.2456781419105
# differential_evolution step 312: f(x)= 2833.2456781419105
# differential_evolution step 313: f(x)= 2833.2456781419105
# differential_evolution step 314: f(x)= 2833.2456781419105
# differential_evolution step 315: f(x)= 2833.2456781419105
# differential_evolution step 316: f(x)= 2833.2456781419105
# differential_evolution step 317: f(x)= 2833.2456781419105
# differential_evolution step 318: f(x)= 2833.2456781419105
# differential_evolution step 319: f(x)= 2833.2456781419105
# differential_evolution step 320: f(x)= 2833.2456781419105
# differential_evolution step 321: f(x)= 2833.2456781419105
# differential_evolution step 322: f(x)= 2833.081285109251
# differential_evolution step 323: f(x)= 2833.081285109251
# differential_evolution step 324: f(x)= 2832.1678260886856
# differential_evolution step 325: f(x)= 2832.1678260886856
# differential_evolution step 326: f(x)= 2832.1678260886856
# differential_evolution step 327: f(x)= 2832.1678260886856
# differential_evolution step 328: f(x)= 2832.1678260886856
# differential_evolution step 329: f(x)= 2832.1678260886856
# differential_evolution step 330: f(x)= 2832.1678260886856
# differential_evolution step 331: f(x)= 2832.1678260886856
# differential_evolution step 332: f(x)= 2832.013933116367
# differential_evolution step 333: f(x)= 2831.910715167968
# differential_evolution step 334: f(x)= 2831.4399033449395
# differential_evolution step 335: f(x)= 2831.4399033449395
# differential_evolution step 336: f(x)= 2831.4399033449395
# differential_evolution step 337: f(x)= 2830.240187528991
# differential_evolution step 338: f(x)= 2830.240187528991
# differential_evolution step 339: f(x)= 2830.240187528991
# differential_evolution step 340: f(x)= 2830.240187528991
# differential_evolution step 341: f(x)= 2830.240187528991
# differential_evolution step 342: f(x)= 2830.240187528991
# differential_evolution step 343: f(x)= 2830.240187528991
# differential_evolution step 344: f(x)= 2830.240187528991
# differential_evolution step 345: f(x)= 2830.240187528991
# differential_evolution step 346: f(x)= 2830.240187528991
# differential_evolution step 347: f(x)= 2830.240187528991
# differential_evolution step 348: f(x)= 2830.240187528991
# differential_evolution step 349: f(x)= 2830.240187528991
# differential_evolution step 350: f(x)= 2830.240187528991
# differential_evolution step 351: f(x)= 2830.240187528991
# differential_evolution step 352: f(x)= 2829.720224876343
# differential_evolution step 353: f(x)= 2829.720224876343
# differential_evolution step 354: f(x)= 2829.720224876343
# differential_evolution step 355: f(x)= 2829.453018608725
# differential_evolution step 356: f(x)= 2829.453018608725
# differential_evolution step 357: f(x)= 2829.453018608725
# differential_evolution step 358: f(x)= 2829.453018608725
# differential_evolution step 359: f(x)= 2829.453018608725
# differential_evolution step 360: f(x)= 2829.453018608725
# differential_evolution step 361: f(x)= 2829.453018608725
# differential_evolution step 362: f(x)= 2829.453018608725
# differential_evolution step 363: f(x)= 2829.045380166124
# differential_evolution step 364: f(x)= 2829.045380166124
# differential_evolution step 365: f(x)= 2828.219293420919
# differential_evolution step 366: f(x)= 2828.219293420919
# differential_evolution step 367: f(x)= 2828.219293420919
# differential_evolution step 368: f(x)= 2827.9715875216384
# differential_evolution step 369: f(x)= 2827.8563887716814
# differential_evolution step 370: f(x)= 2827.8563887716814
# differential_evolution step 371: f(x)= 2827.8563887716814
# differential_evolution step 372: f(x)= 2827.8563887716814
# differential_evolution step 373: f(x)= 2827.8563887716814
# differential_evolution step 374: f(x)= 2827.8563887716814
# differential_evolution step 375: f(x)= 2827.1236214061823
# differential_evolution step 376: f(x)= 2827.1236214061823
# differential_evolution step 377: f(x)= 2826.336253739031
# differential_evolution step 378: f(x)= 2826.1464455585733
# differential_evolution step 379: f(x)= 2826.1464455585733
# differential_evolution step 380: f(x)= 2826.1464455585733
# differential_evolution step 381: f(x)= 2826.1464455585733
# differential_evolution step 382: f(x)= 2826.1464455585733
# differential_evolution step 383: f(x)= 2826.1464455585733
# differential_evolution step 384: f(x)= 2826.1464455585733
# differential_evolution step 385: f(x)= 2826.1464455585733
# differential_evolution step 386: f(x)= 2825.8530012702013
# differential_evolution step 387: f(x)= 2825.8530012702013
# differential_evolution step 388: f(x)= 2825.7047453338446
# differential_evolution step 389: f(x)= 2825.439303876291
# differential_evolution step 390: f(x)= 2825.439303876291
# differential_evolution step 391: f(x)= 2825.439303876291
# differential_evolution step 392: f(x)= 2825.43776182413
# differential_evolution step 393: f(x)= 2825.43776182413
# differential_evolution step 394: f(x)= 2825.43776182413
# differential_evolution step 395: f(x)= 2825.43776182413
# differential_evolution step 396: f(x)= 2825.43776182413
# differential_evolution step 397: f(x)= 2824.7214015641193
# differential_evolution step 398: f(x)= 2824.7214015641193
# differential_evolution step 399: f(x)= 2824.7214015641193
# differential_evolution step 400: f(x)= 2824.7214015641193
# differential_evolution step 401: f(x)= 2824.7214015641193
# differential_evolution step 402: f(x)= 2824.7214015641193
# differential_evolution step 403: f(x)= 2824.6920451491847
# differential_evolution step 404: f(x)= 2824.6920451491847
# differential_evolution step 405: f(x)= 2824.6784592046506
# differential_evolution step 406: f(x)= 2824.6784592046506
# differential_evolution step 407: f(x)= 2824.6784592046506
# differential_evolution step 408: f(x)= 2824.565350275392
# differential_evolution step 409: f(x)= 2824.565350275392
# differential_evolution step 410: f(x)= 2824.565350275392
# differential_evolution step 411: f(x)= 2824.565350275392
# differential_evolution step 412: f(x)= 2824.565350275392
# differential_evolution step 413: f(x)= 2824.4709224208227
# differential_evolution step 414: f(x)= 2824.4709224208227
# differential_evolution step 415: f(x)= 2824.4709224208227
# differential_evolution step 416: f(x)= 2824.390712313954
# differential_evolution step 417: f(x)= 2824.390712313954
# differential_evolution step 418: f(x)= 2824.390712313954
# differential_evolution step 419: f(x)= 2824.390712313954
# differential_evolution step 420: f(x)= 2824.1939841288977
# differential_evolution step 421: f(x)= 2824.1939841288977
# differential_evolution step 422: f(x)= 2823.654037384647
# differential_evolution step 423: f(x)= 2823.654037384647
# differential_evolution step 424: f(x)= 2823.212536237684
# differential_evolution step 425: f(x)= 2823.212536237684
# differential_evolution step 426: f(x)= 2823.212536237684
# differential_evolution step 427: f(x)= 2823.212536237684
# differential_evolution step 428: f(x)= 2823.212536237684
# differential_evolution step 429: f(x)= 2823.212536237684
# differential_evolution step 430: f(x)= 2823.212536237684
# differential_evolution step 431: f(x)= 2823.212536237684
# differential_evolution step 432: f(x)= 2823.212536237684
# differential_evolution step 433: f(x)= 2823.212536237684
# differential_evolution step 434: f(x)= 2823.212536237684
# differential_evolution step 435: f(x)= 2823.1344285687237
# differential_evolution step 436: f(x)= 2822.502648044387
# differential_evolution step 437: f(x)= 2822.502648044387
# differential_evolution step 438: f(x)= 2822.502648044387
# differential_evolution step 439: f(x)= 2822.502648044387
# differential_evolution step 440: f(x)= 2822.502648044387
# differential_evolution step 441: f(x)= 2821.939760494055
# differential_evolution step 442: f(x)= 2821.939760494055
# differential_evolution step 443: f(x)= 2821.939760494055
# differential_evolution step 444: f(x)= 2821.939760494055
# differential_evolution step 445: f(x)= 2821.939760494055
# differential_evolution step 446: f(x)= 2821.939760494055
# differential_evolution step 447: f(x)= 2821.939760494055
# differential_evolution step 448: f(x)= 2821.939760494055
# differential_evolution step 449: f(x)= 2821.939760494055
# differential_evolution step 450: f(x)= 2821.939760494055
# differential_evolution step 451: f(x)= 2821.939760494055
# differential_evolution step 452: f(x)= 2821.939760494055
# differential_evolution step 453: f(x)= 2821.939760494055
# differential_evolution step 454: f(x)= 2821.939760494055
# differential_evolution step 455: f(x)= 2821.939760494055
# differential_evolution step 456: f(x)= 2821.939760494055
# differential_evolution step 457: f(x)= 2821.939760494055
# differential_evolution step 458: f(x)= 2821.939760494055
# differential_evolution step 459: f(x)= 2821.939760494055
# differential_evolution step 460: f(x)= 2821.916757748206
# differential_evolution step 461: f(x)= 2821.916757748206
# differential_evolution step 462: f(x)= 2821.916757748206
# differential_evolution step 463: f(x)= 2821.916757748206
# differential_evolution step 464: f(x)= 2821.468611091467
# differential_evolution step 465: f(x)= 2821.468611091467
# differential_evolution step 466: f(x)= 2821.468611091467
# differential_evolution step 467: f(x)= 2821.468611091467
# differential_evolution step 468: f(x)= 2821.243292190442
# differential_evolution step 469: f(x)= 2821.199806317862
# differential_evolution step 470: f(x)= 2821.199806317862
# differential_evolution step 471: f(x)= 2819.6256831795117
# differential_evolution step 472: f(x)= 2818.5649810017803
# differential_evolution step 473: f(x)= 2818.5649810017803
# differential_evolution step 474: f(x)= 2818.5649810017803
# differential_evolution step 475: f(x)= 2818.5649810017803
# differential_evolution step 476: f(x)= 2818.5649810017803
# differential_evolution step 477: f(x)= 2818.5649810017803
# differential_evolution step 478: f(x)= 2818.5649810017803
# differential_evolution step 479: f(x)= 2818.5649810017803
# differential_evolution step 480: f(x)= 2818.5649810017803
# differential_evolution step 481: f(x)= 2818.477419278515
# differential_evolution step 482: f(x)= 2818.477419278515
# differential_evolution step 483: f(x)= 2818.477419278515
# differential_evolution step 484: f(x)= 2818.477419278515
# differential_evolution step 485: f(x)= 2818.477419278515
# differential_evolution step 486: f(x)= 2818.477419278515
# differential_evolution step 487: f(x)= 2818.477419278515
# differential_evolution step 488: f(x)= 2818.477419278515
# differential_evolution step 489: f(x)= 2818.477419278515
# differential_evolution step 490: f(x)= 2818.477419278515
# differential_evolution step 491: f(x)= 2818.477419278515
# differential_evolution step 492: f(x)= 2818.477419278515
# differential_evolution step 493: f(x)= 2818.477419278515
# differential_evolution step 494: f(x)= 2818.477419278515
# differential_evolution step 495: f(x)= 2818.477419278515
# differential_evolution step 496: f(x)= 2818.477419278515
# differential_evolution step 497: f(x)= 2818.477419278515
# differential_evolution step 498: f(x)= 2818.477419278515
# differential_evolution step 499: f(x)= 2818.477419278515
# differential_evolution step 500: f(x)= 2818.477419278515
# differential_evolution step 501: f(x)= 2818.4568795832115
# differential_evolution step 502: f(x)= 2818.4568795832115
# differential_evolution step 503: f(x)= 2818.4568795832115
# differential_evolution step 504: f(x)= 2818.4568795832115
# differential_evolution step 505: f(x)= 2818.4568795832115
# differential_evolution step 506: f(x)= 2818.4568795832115
# differential_evolution step 507: f(x)= 2818.4568795832115
# differential_evolution step 508: f(x)= 2818.4568795832115
# differential_evolution step 509: f(x)= 2818.4568795832115
# differential_evolution step 510: f(x)= 2818.4568795832115
# differential_evolution step 511: f(x)= 2818.4568795832115
# differential_evolution step 512: f(x)= 2818.4568795832115
# differential_evolution step 513: f(x)= 2818.4568795832115
# differential_evolution step 514: f(x)= 2818.4568795832115
# differential_evolution step 515: f(x)= 2818.4568795832115
# differential_evolution step 516: f(x)= 2818.3751664527394
# differential_evolution step 517: f(x)= 2818.3751664527394
# differential_evolution step 518: f(x)= 2818.3751664527394
# differential_evolution step 519: f(x)= 2818.3751664527394
# differential_evolution step 520: f(x)= 2818.3751664527394
# differential_evolution step 521: f(x)= 2818.3751664527394
# differential_evolution step 522: f(x)= 2818.3751664527394
# differential_evolution step 523: f(x)= 2818.3751664527394
# differential_evolution step 524: f(x)= 2818.344180000598
# differential_evolution step 525: f(x)= 2817.8793912818005
# differential_evolution step 526: f(x)= 2817.6253972451154
# differential_evolution step 527: f(x)= 2817.6253972451154
# differential_evolution step 528: f(x)= 2817.6253972451154
# differential_evolution step 529: f(x)= 2817.6253972451154
# differential_evolution step 530: f(x)= 2817.6253972451154
# differential_evolution step 531: f(x)= 2817.6253972451154
# differential_evolution step 532: f(x)= 2817.6253972451154
# differential_evolution step 533: f(x)= 2817.6253972451154
# differential_evolution step 534: f(x)= 2817.6253972451154
# differential_evolution step 535: f(x)= 2817.6253972451154
# differential_evolution step 536: f(x)= 2817.6253972451154
# differential_evolution step 537: f(x)= 2817.6253972451154
# differential_evolution step 538: f(x)= 2817.6253972451154
# differential_evolution step 539: f(x)= 2817.6253972451154
# differential_evolution step 540: f(x)= 2817.6253972451154
# differential_evolution step 541: f(x)= 2817.6253972451154
# differential_evolution step 542: f(x)= 2817.6253972451154
# differential_evolution step 543: f(x)= 2817.6253972451154
# differential_evolution step 544: f(x)= 2817.6253972451154
# differential_evolution step 545: f(x)= 2817.6253972451154
# differential_evolution step 546: f(x)= 2817.6253972451154
# differential_evolution step 547: f(x)= 2817.6253972451154
# differential_evolution step 548: f(x)= 2817.6253972451154
# differential_evolution step 549: f(x)= 2817.6253972451154
# differential_evolution step 550: f(x)= 2817.6253972451154
# differential_evolution step 551: f(x)= 2817.6253972451154
# differential_evolution step 552: f(x)= 2817.6253972451154
# differential_evolution step 553: f(x)= 2817.6253972451154
# differential_evolution step 554: f(x)= 2817.6253972451154
# differential_evolution step 555: f(x)= 2817.6253972451154
# differential_evolution step 556: f(x)= 2817.6253972451154
# differential_evolution step 557: f(x)= 2817.6253972451154
# differential_evolution step 558: f(x)= 2817.6253972451154
# differential_evolution step 559: f(x)= 2817.6253972451154
# differential_evolution step 560: f(x)= 2817.6253972451154
# differential_evolution step 561: f(x)= 2817.6253972451154
# differential_evolution step 562: f(x)= 2817.6253972451154
# differential_evolution step 563: f(x)= 2817.6253972451154
# differential_evolution step 564: f(x)= 2817.6253972451154
# differential_evolution step 565: f(x)= 2817.6253972451154
# differential_evolution step 566: f(x)= 2817.6253972451154
# differential_evolution step 567: f(x)= 2817.573203497366
# differential_evolution step 568: f(x)= 2817.5246061207595
# differential_evolution step 569: f(x)= 2817.5246061207595
# differential_evolution step 570: f(x)= 2817.5246061207595
# differential_evolution step 571: f(x)= 2817.1482846533836
# differential_evolution step 572: f(x)= 2817.1482846533836
# differential_evolution step 573: f(x)= 2817.1482846533836
# differential_evolution step 574: f(x)= 2816.6294564973778
# differential_evolution step 575: f(x)= 2816.5523557733773
# differential_evolution step 576: f(x)= 2816.308865332329
# differential_evolution step 577: f(x)= 2816.308865332329
# differential_evolution step 578: f(x)= 2816.308865332329
# differential_evolution step 579: f(x)= 2816.308865332329
# differential_evolution step 580: f(x)= 2816.3006704824975
# differential_evolution step 581: f(x)= 2816.3006704824975
# differential_evolution step 582: f(x)= 2816.3006704824975
# differential_evolution step 583: f(x)= 2816.3006704824975
# differential_evolution step 584: f(x)= 2816.272490928354
# differential_evolution step 585: f(x)= 2815.556622283037
# differential_evolution step 586: f(x)= 2815.556622283037
# differential_evolution step 587: f(x)= 2815.556622283037
# differential_evolution step 588: f(x)= 2815.556622283037
# differential_evolution step 589: f(x)= 2815.556622283037
# differential_evolution step 590: f(x)= 2815.556622283037
# differential_evolution step 591: f(x)= 2815.556622283037
# differential_evolution step 592: f(x)= 2815.556622283037
# differential_evolution step 593: f(x)= 2815.556622283037
# differential_evolution step 594: f(x)= 2815.556622283037
# differential_evolution step 595: f(x)= 2815.2757647370963
# differential_evolution step 596: f(x)= 2815.2757647370963
# differential_evolution step 597: f(x)= 2815.2635665596613
# differential_evolution step 598: f(x)= 2815.2635665596613
# differential_evolution step 599: f(x)= 2815.2635665596613
# differential_evolution step 600: f(x)= 2815.2635665596613
# differential_evolution step 601: f(x)= 2815.2635665596613
# differential_evolution step 602: f(x)= 2815.2635665596613
# differential_evolution step 603: f(x)= 2815.2635665596613
# differential_evolution step 604: f(x)= 2815.2635665596613
# differential_evolution step 605: f(x)= 2815.079053959404
# differential_evolution step 606: f(x)= 2815.079053959404
# differential_evolution step 607: f(x)= 2815.079053959404
# differential_evolution step 608: f(x)= 2815.079053959404
# differential_evolution step 609: f(x)= 2815.079053959404
# differential_evolution step 610: f(x)= 2815.079053959404
# differential_evolution step 611: f(x)= 2815.079053959404
# differential_evolution step 612: f(x)= 2815.079053959404
# differential_evolution step 613: f(x)= 2815.079053959404
# differential_evolution step 614: f(x)= 2815.079053959404
# differential_evolution step 615: f(x)= 2815.079053959404
# differential_evolution step 616: f(x)= 2814.9283895404888
# differential_evolution step 617: f(x)= 2814.9283895404888
# differential_evolution step 618: f(x)= 2814.8033983353557
# differential_evolution step 619: f(x)= 2814.727288994905
# differential_evolution step 620: f(x)= 2814.727288994905
# differential_evolution step 621: f(x)= 2814.727288994905
# differential_evolution step 622: f(x)= 2814.727288994905
# differential_evolution step 623: f(x)= 2814.705676027953
# differential_evolution step 624: f(x)= 2814.705676027953
# differential_evolution step 625: f(x)= 2814.676992449131
# differential_evolution step 626: f(x)= 2814.676992449131
# differential_evolution step 627: f(x)= 2814.676992449131
# differential_evolution step 628: f(x)= 2814.4733723043496
# differential_evolution step 629: f(x)= 2814.4733723043496
# differential_evolution step 630: f(x)= 2814.4733723043496
# differential_evolution step 631: f(x)= 2814.4733723043496
# differential_evolution step 632: f(x)= 2814.4733723043496
# differential_evolution step 633: f(x)= 2814.4733723043496
# differential_evolution step 634: f(x)= 2814.4733723043496
# differential_evolution step 635: f(x)= 2814.4733723043496
# differential_evolution step 636: f(x)= 2814.4733723043496
# differential_evolution step 637: f(x)= 2814.370461777392
# differential_evolution step 638: f(x)= 2814.370461777392
# differential_evolution step 639: f(x)= 2814.370461777392
# differential_evolution step 640: f(x)= 2814.370461777392
# differential_evolution step 641: f(x)= 2814.368685192771
# differential_evolution step 642: f(x)= 2814.368685192771
# differential_evolution step 643: f(x)= 2814.368685192771
# differential_evolution step 644: f(x)= 2814.368685192771
# differential_evolution step 645: f(x)= 2814.368685192771
# differential_evolution step 646: f(x)= 2814.368685192771
# differential_evolution step 647: f(x)= 2814.368685192771
# differential_evolution step 648: f(x)= 2814.368685192771
# differential_evolution step 649: f(x)= 2814.368685192771
# differential_evolution step 650: f(x)= 2814.368685192771
# differential_evolution step 651: f(x)= 2814.368685192771
# differential_evolution step 652: f(x)= 2814.368685192771
# differential_evolution step 653: f(x)= 2814.368685192771
# differential_evolution step 654: f(x)= 2814.368685192771
# differential_evolution step 655: f(x)= 2814.147052785452
# differential_evolution step 656: f(x)= 2814.1466745472126
# differential_evolution step 657: f(x)= 2814.1466745472126
# differential_evolution step 658: f(x)= 2814.1466745472126
# differential_evolution step 659: f(x)= 2814.1466745472126
# differential_evolution step 660: f(x)= 2814.1466745472126
# differential_evolution step 661: f(x)= 2814.1466745472126
# differential_evolution step 662: f(x)= 2814.1466745472126
# differential_evolution step 663: f(x)= 2814.1466745472126
# differential_evolution step 664: f(x)= 2814.1466745472126
# differential_evolution step 665: f(x)= 2814.1466745472126
# differential_evolution step 666: f(x)= 2814.1466745472126
# differential_evolution step 667: f(x)= 2814.1466745472126
# differential_evolution step 668: f(x)= 2814.1466745472126
# differential_evolution step 669: f(x)= 2814.1466745472126
# differential_evolution step 670: f(x)= 2814.1466745472126
# differential_evolution step 671: f(x)= 2814.1466745472126
# differential_evolution step 672: f(x)= 2814.1466745472126
# differential_evolution step 673: f(x)= 2814.066634682171
# differential_evolution step 674: f(x)= 2814.066634682171
# differential_evolution step 675: f(x)= 2814.066634682171
# differential_evolution step 676: f(x)= 2814.066634682171
# differential_evolution step 677: f(x)= 2814.066634682171
# differential_evolution step 678: f(x)= 2814.015897346115
# differential_evolution step 679: f(x)= 2813.840781553885
# differential_evolution step 680: f(x)= 2813.8196820217067
# differential_evolution step 681: f(x)= 2813.8196820217067
# differential_evolution step 682: f(x)= 2813.8196820217067
# differential_evolution step 683: f(x)= 2813.8196820217067
# differential_evolution step 684: f(x)= 2813.8196820217067
# differential_evolution step 685: f(x)= 2813.8196820217067
# differential_evolution step 686: f(x)= 2813.6680087358554
# differential_evolution step 687: f(x)= 2813.380008604524
# differential_evolution step 688: f(x)= 2812.9845777041774
# differential_evolution step 689: f(x)= 2812.823644874189
# differential_evolution step 690: f(x)= 2812.823644874189
# differential_evolution step 691: f(x)= 2812.773505393519
# differential_evolution step 692: f(x)= 2812.773505393519
# differential_evolution step 693: f(x)= 2812.4666500159997
# differential_evolution step 694: f(x)= 2812.4666500159997
# differential_evolution step 695: f(x)= 2812.406714459537
# differential_evolution step 696: f(x)= 2812.406714459537
# differential_evolution step 697: f(x)= 2812.350331605323
# differential_evolution step 698: f(x)= 2812.350331605323
# differential_evolution step 699: f(x)= 2812.350331605323
# differential_evolution step 700: f(x)= 2812.350331605323
# differential_evolution step 701: f(x)= 2812.2644126618984
# differential_evolution step 702: f(x)= 2812.2644126618984
# differential_evolution step 703: f(x)= 2812.2644126618984
# differential_evolution step 704: f(x)= 2812.2644126618984
# differential_evolution step 705: f(x)= 2811.975267201117
# differential_evolution step 706: f(x)= 2811.975267201117
# differential_evolution step 707: f(x)= 2811.7180615308807
# differential_evolution step 708: f(x)= 2811.7180615308807
# differential_evolution step 709: f(x)= 2811.7180615308807
# differential_evolution step 710: f(x)= 2811.7180615308807
# differential_evolution step 711: f(x)= 2811.7180615308807
# differential_evolution step 712: f(x)= 2811.7180615308807
# differential_evolution step 713: f(x)= 2811.7180615308807
# differential_evolution step 714: f(x)= 2811.397378245696
# differential_evolution step 715: f(x)= 2811.397378245696
# differential_evolution step 716: f(x)= 2811.397378245696
# differential_evolution step 717: f(x)= 2811.397378245696
# differential_evolution step 718: f(x)= 2811.397378245696
# differential_evolution step 719: f(x)= 2811.397378245696
# differential_evolution step 720: f(x)= 2811.397378245696
# differential_evolution step 721: f(x)= 2811.397378245696
# differential_evolution step 722: f(x)= 2811.397378245696
# differential_evolution step 723: f(x)= 2811.397378245696
# differential_evolution step 724: f(x)= 2811.397378245696
# differential_evolution step 725: f(x)= 2811.397378245696
# differential_evolution step 726: f(x)= 2811.397378245696
# differential_evolution step 727: f(x)= 2811.397378245696
# differential_evolution step 728: f(x)= 2811.397378245696
# differential_evolution step 729: f(x)= 2811.397378245696
# differential_evolution step 730: f(x)= 2811.397378245696
# differential_evolution step 731: f(x)= 2811.397378245696
# differential_evolution step 732: f(x)= 2811.397378245696
# differential_evolution step 733: f(x)= 2811.397378245696
# differential_evolution step 734: f(x)= 2811.397378245696
# differential_evolution step 735: f(x)= 2811.397378245696
# differential_evolution step 736: f(x)= 2811.397378245696
# differential_evolution step 737: f(x)= 2811.397378245696
# differential_evolution step 738: f(x)= 2811.397378245696
# differential_evolution step 739: f(x)= 2811.397378245696
# differential_evolution step 740: f(x)= 2811.397378245696
# differential_evolution step 741: f(x)= 2811.397378245696
# differential_evolution step 742: f(x)= 2811.397378245696
# differential_evolution step 743: f(x)= 2811.397378245696
# differential_evolution step 744: f(x)= 2811.397378245696
# differential_evolution step 745: f(x)= 2811.397378245696
# differential_evolution step 746: f(x)= 2811.397378245696
# differential_evolution step 747: f(x)= 2811.362870877926
# differential_evolution step 748: f(x)= 2811.362870877926
# differential_evolution step 749: f(x)= 2811.362870877926
# differential_evolution step 750: f(x)= 2811.362870877926
# differential_evolution step 751: f(x)= 2811.362870877926
# differential_evolution step 752: f(x)= 2811.362870877926
# differential_evolution step 753: f(x)= 2811.362870877926
# differential_evolution step 754: f(x)= 2811.362870877926
# differential_evolution step 755: f(x)= 2811.362870877926
# differential_evolution step 756: f(x)= 2811.362870877926
# differential_evolution step 757: f(x)= 2811.362870877926
# differential_evolution step 758: f(x)= 2811.362870877926
# differential_evolution step 759: f(x)= 2811.362870877926
# differential_evolution step 760: f(x)= 2811.362870877926
# differential_evolution step 761: f(x)= 2811.362870877926
# differential_evolution step 762: f(x)= 2811.362870877926
# differential_evolution step 763: f(x)= 2811.362870877926
# differential_evolution step 764: f(x)= 2811.3472272321374
# differential_evolution step 765: f(x)= 2811.3472272321374
# differential_evolution step 766: f(x)= 2811.3472272321374
# differential_evolution step 767: f(x)= 2811.3472272321374
# differential_evolution step 768: f(x)= 2811.3472272321374
# differential_evolution step 769: f(x)= 2811.3472272321374
# differential_evolution step 770: f(x)= 2811.3472272321374
# differential_evolution step 771: f(x)= 2811.3472272321374
# differential_evolution step 772: f(x)= 2811.0210918846765
# differential_evolution step 773: f(x)= 2811.0210918846765
# differential_evolution step 774: f(x)= 2811.0210918846765
# differential_evolution step 775: f(x)= 2811.0210918846765
# differential_evolution step 776: f(x)= 2811.0210918846765
# differential_evolution step 777: f(x)= 2811.0210918846765
# differential_evolution step 778: f(x)= 2811.0210918846765
# differential_evolution step 779: f(x)= 2811.0210918846765
# differential_evolution step 780: f(x)= 2811.0210918846765
# differential_evolution step 781: f(x)= 2811.0210918846765
# differential_evolution step 782: f(x)= 2811.0210918846765
# differential_evolution step 783: f(x)= 2811.0210918846765
# differential_evolution step 784: f(x)= 2811.0210918846765
# differential_evolution step 785: f(x)= 2811.0210918846765
# differential_evolution step 786: f(x)= 2811.0210918846765
# differential_evolution step 787: f(x)= 2811.0210918846765
# differential_evolution step 788: f(x)= 2811.0210918846765
# differential_evolution step 789: f(x)= 2811.0210918846765
# differential_evolution step 790: f(x)= 2811.0210918846765
# differential_evolution step 791: f(x)= 2811.0210918846765
# differential_evolution step 792: f(x)= 2811.0210918846765
# differential_evolution step 793: f(x)= 2811.0210918846765
# differential_evolution step 794: f(x)= 2811.0210918846765
# differential_evolution step 795: f(x)= 2811.0210918846765
# differential_evolution step 796: f(x)= 2810.9515787649975
# differential_evolution step 797: f(x)= 2810.9515787649975
# differential_evolution step 798: f(x)= 2810.9515787649975
# differential_evolution step 799: f(x)= 2810.9515787649975
# differential_evolution step 800: f(x)= 2810.9515787649975
# differential_evolution step 801: f(x)= 2810.873250724505
# differential_evolution step 802: f(x)= 2810.873250724505
# differential_evolution step 803: f(x)= 2810.873250724505
# differential_evolution step 804: f(x)= 2810.873250724505
# differential_evolution step 805: f(x)= 2810.332790866401
# differential_evolution step 806: f(x)= 2810.332790866401
# differential_evolution step 807: f(x)= 2810.332790866401
# differential_evolution step 808: f(x)= 2810.332790866401
# differential_evolution step 809: f(x)= 2810.332790866401
# differential_evolution step 810: f(x)= 2810.332790866401
# differential_evolution step 811: f(x)= 2810.332790866401
# differential_evolution step 812: f(x)= 2810.332790866401
# differential_evolution step 813: f(x)= 2810.332790866401
# differential_evolution step 814: f(x)= 2810.332790866401
# differential_evolution step 815: f(x)= 2810.332790866401
# differential_evolution step 816: f(x)= 2810.332790866401
# differential_evolution step 817: f(x)= 2810.332790866401
# differential_evolution step 818: f(x)= 2810.332790866401
# differential_evolution step 819: f(x)= 2810.332790866401
# differential_evolution step 820: f(x)= 2810.332790866401
# differential_evolution step 821: f(x)= 2810.332790866401
# differential_evolution step 822: f(x)= 2810.332790866401
# differential_evolution step 823: f(x)= 2810.332790866401
# differential_evolution step 824: f(x)= 2810.332790866401
# differential_evolution step 825: f(x)= 2810.332790866401
# differential_evolution step 826: f(x)= 2810.332790866401
# differential_evolution step 827: f(x)= 2810.332790866401
# differential_evolution step 828: f(x)= 2810.332790866401
# differential_evolution step 829: f(x)= 2810.332790866401
# differential_evolution step 830: f(x)= 2810.332790866401
# differential_evolution step 831: f(x)= 2810.332790866401
# differential_evolution step 832: f(x)= 2810.332790866401
# differential_evolution step 833: f(x)= 2810.332790866401
# differential_evolution step 834: f(x)= 2810.332790866401
# differential_evolution step 835: f(x)= 2810.332790866401
# differential_evolution step 836: f(x)= 2810.332790866401
# differential_evolution step 837: f(x)= 2810.332790866401
# differential_evolution step 838: f(x)= 2810.332790866401
# differential_evolution step 839: f(x)= 2810.1771446382127
# differential_evolution step 840: f(x)= 2810.1771446382127
# differential_evolution step 841: f(x)= 2810.1771446382127
# differential_evolution step 842: f(x)= 2810.1771446382127
# differential_evolution step 843: f(x)= 2810.1771446382127
# differential_evolution step 844: f(x)= 2810.1771446382127
# differential_evolution step 845: f(x)= 2810.1059555440715
# differential_evolution step 846: f(x)= 2810.1059555440715
# differential_evolution step 847: f(x)= 2809.8439067276977
# differential_evolution step 848: f(x)= 2809.8439067276977
# differential_evolution step 849: f(x)= 2809.8439067276977
# differential_evolution step 850: f(x)= 2809.5315342918825
# differential_evolution step 851: f(x)= 2809.5315342918825
# differential_evolution step 852: f(x)= 2809.300679929217
# differential_evolution step 853: f(x)= 2809.300679929217
# differential_evolution step 854: f(x)= 2809.273475097149
# differential_evolution step 855: f(x)= 2808.735830493381
# differential_evolution step 856: f(x)= 2808.440363906686
# differential_evolution step 857: f(x)= 2808.440363906686
# differential_evolution step 858: f(x)= 2808.440363906686
# differential_evolution step 859: f(x)= 2808.440363906686
# differential_evolution step 860: f(x)= 2808.440363906686
# differential_evolution step 861: f(x)= 2808.440363906686
# differential_evolution step 862: f(x)= 2808.440363906686
# differential_evolution step 863: f(x)= 2808.440363906686
# differential_evolution step 864: f(x)= 2808.440363906686
# differential_evolution step 865: f(x)= 2808.440363906686
# differential_evolution step 866: f(x)= 2808.440363906686
# differential_evolution step 867: f(x)= 2808.440363906686
# differential_evolution step 868: f(x)= 2808.440363906686
# differential_evolution step 869: f(x)= 2808.3085843486347
# differential_evolution step 870: f(x)= 2808.150041914765
# differential_evolution step 871: f(x)= 2807.807621379511
# differential_evolution step 872: f(x)= 2807.807621379511
# differential_evolution step 873: f(x)= 2807.792347589206
# differential_evolution step 874: f(x)= 2807.792347589206
# differential_evolution step 875: f(x)= 2807.7696654408414
# differential_evolution step 876: f(x)= 2807.475162466753
# differential_evolution step 877: f(x)= 2807.446674581825
# differential_evolution step 878: f(x)= 2807.3425920715654
# differential_evolution step 879: f(x)= 2807.3425920715654
# differential_evolution step 880: f(x)= 2807.3425920715654
# differential_evolution step 881: f(x)= 2807.3425920715654
# differential_evolution step 882: f(x)= 2807.2154185912154
# differential_evolution step 883: f(x)= 2807.2154185912154
# differential_evolution step 884: f(x)= 2807.2154185912154
# differential_evolution step 885: f(x)= 2807.2154185912154
# differential_evolution step 886: f(x)= 2806.5994206636938
# differential_evolution step 887: f(x)= 2806.4712482340547
# differential_evolution step 888: f(x)= 2806.4712482340547
# differential_evolution step 889: f(x)= 2806.3946761258244
# differential_evolution step 890: f(x)= 2806.3946761258244
# differential_evolution step 891: f(x)= 2806.053522777643
# differential_evolution step 892: f(x)= 2806.053522777643
# differential_evolution step 893: f(x)= 2806.053522777643
# differential_evolution step 894: f(x)= 2805.9239721513113
# differential_evolution step 895: f(x)= 2805.9239721513113
# differential_evolution step 896: f(x)= 2805.9239721513113
# differential_evolution step 897: f(x)= 2805.9239721513113
# differential_evolution step 898: f(x)= 2805.8049201470994
# differential_evolution step 899: f(x)= 2805.625230818404
# differential_evolution step 900: f(x)= 2805.625230818404
# differential_evolution step 901: f(x)= 2805.625230818404
# differential_evolution step 902: f(x)= 2805.625230818404
# differential_evolution step 903: f(x)= 2805.625230818404
# differential_evolution step 904: f(x)= 2805.625230818404
# differential_evolution step 905: f(x)= 2805.625230818404
# differential_evolution step 906: f(x)= 2805.500643399489
# differential_evolution step 907: f(x)= 2805.500643399489
# differential_evolution step 908: f(x)= 2805.500643399489
# differential_evolution step 909: f(x)= 2805.133279839703
# differential_evolution step 910: f(x)= 2805.133279839703
# differential_evolution step 911: f(x)= 2805.133279839703
# differential_evolution step 912: f(x)= 2804.873691772601
# differential_evolution step 913: f(x)= 2804.873691772601
# differential_evolution step 914: f(x)= 2804.873691772601
# differential_evolution step 915: f(x)= 2804.873691772601
# differential_evolution step 916: f(x)= 2804.8510220399708
# differential_evolution step 917: f(x)= 2804.8510220399708
# differential_evolution step 918: f(x)= 2804.8510220399708
# differential_evolution step 919: f(x)= 2804.8510220399708
# differential_evolution step 920: f(x)= 2804.8510220399708
# differential_evolution step 921: f(x)= 2804.831737543617
# differential_evolution step 922: f(x)= 2804.336900431839
# differential_evolution step 923: f(x)= 2804.336900431839
# differential_evolution step 924: f(x)= 2804.336900431839
# differential_evolution step 925: f(x)= 2803.870845026987
# differential_evolution step 926: f(x)= 2803.870845026987
# differential_evolution step 927: f(x)= 2803.870845026987
# differential_evolution step 928: f(x)= 2803.870845026987
# differential_evolution step 929: f(x)= 2803.870845026987
# differential_evolution step 930: f(x)= 2803.858975152307
# differential_evolution step 931: f(x)= 2803.858975152307
# differential_evolution step 932: f(x)= 2803.5732681534564
# differential_evolution step 933: f(x)= 2803.5732681534564
# differential_evolution step 934: f(x)= 2803.5070082403718
# differential_evolution step 935: f(x)= 2803.5070082403718
# differential_evolution step 936: f(x)= 2803.5070082403718
# differential_evolution step 937: f(x)= 2803.3543988285232
# differential_evolution step 938: f(x)= 2803.3543988285232
# differential_evolution step 939: f(x)= 2803.3330325457905
# differential_evolution step 940: f(x)= 2803.2792464952904
# differential_evolution step 941: f(x)= 2803.2792464952904
# differential_evolution step 942: f(x)= 2803.2792464952904
# differential_evolution step 943: f(x)= 2803.172563253946
# differential_evolution step 944: f(x)= 2803.172563253946
# differential_evolution step 945: f(x)= 2803.172563253946
# differential_evolution step 946: f(x)= 2803.172563253946
# differential_evolution step 947: f(x)= 2803.172563253946
# differential_evolution step 948: f(x)= 2803.172563253946
# differential_evolution step 949: f(x)= 2803.102145993408
# differential_evolution step 950: f(x)= 2803.0068223667377
# differential_evolution step 951: f(x)= 2803.0068223667377
# differential_evolution step 952: f(x)= 2802.9568459922093
# differential_evolution step 953: f(x)= 2802.650299523915
# differential_evolution step 954: f(x)= 2802.490525471041
# differential_evolution step 955: f(x)= 2802.249460949517
# differential_evolution step 956: f(x)= 2802.249460949517
# differential_evolution step 957: f(x)= 2802.249460949517
# differential_evolution step 958: f(x)= 2802.249460949517
# differential_evolution step 959: f(x)= 2801.8336282692335
# differential_evolution step 960: f(x)= 2801.7556970294413
# differential_evolution step 961: f(x)= 2801.7556970294413
# differential_evolution step 962: f(x)= 2801.7556970294413
# differential_evolution step 963: f(x)= 2801.7556970294413
# differential_evolution step 964: f(x)= 2801.7556970294413
# differential_evolution step 965: f(x)= 2801.7556970294413
# differential_evolution step 966: f(x)= 2801.7556970294413
# differential_evolution step 967: f(x)= 2801.7556970294413
# differential_evolution step 968: f(x)= 2801.5772177270433
# differential_evolution step 969: f(x)= 2801.5514517314327
# differential_evolution step 970: f(x)= 2801.5514517314327
# differential_evolution step 971: f(x)= 2801.5514517314327
# differential_evolution step 972: f(x)= 2801.5514517314327
# differential_evolution step 973: f(x)= 2801.350520167785
# differential_evolution step 974: f(x)= 2801.350520167785
# differential_evolution step 975: f(x)= 2801.350520167785
# differential_evolution step 976: f(x)= 2801.350520167785
# differential_evolution step 977: f(x)= 2801.350520167785
# differential_evolution step 978: f(x)= 2800.9907248035915
# differential_evolution step 979: f(x)= 2800.9907248035915
# differential_evolution step 980: f(x)= 2800.9907248035915
# differential_evolution step 981: f(x)= 2800.9907248035915
# differential_evolution step 982: f(x)= 2800.9907248035915
# differential_evolution step 983: f(x)= 2800.9907248035915
# differential_evolution step 984: f(x)= 2800.9907248035915
# differential_evolution step 985: f(x)= 2800.9907248035915
# differential_evolution step 986: f(x)= 2800.9907248035915
# differential_evolution step 987: f(x)= 2800.9907248035915
# differential_evolution step 988: f(x)= 2800.9907248035915
# differential_evolution step 989: f(x)= 2800.9907248035915
# differential_evolution step 990: f(x)= 2800.943009832707
# differential_evolution step 991: f(x)= 2800.943009832707
# differential_evolution step 992: f(x)= 2800.7520969005445
# differential_evolution step 993: f(x)= 2800.7520969005445
# differential_evolution step 994: f(x)= 2800.7520969005445
# differential_evolution step 995: f(x)= 2800.7520969005445
# differential_evolution step 996: f(x)= 2800.6016217498086
# differential_evolution step 997: f(x)= 2800.6016217498086
# differential_evolution step 998: f(x)= 2800.6016217498086
# differential_evolution step 999: f(x)= 2800.6016217498086
# differential_evolution step 1000: f(x)= 2800.6016217498086
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=99.9901, r_e=3.8184, n=0.7375, x_0=40.7200
# Sérsic 2: I_e=1.2666, r_e=49.9975, n=2.5022, x_0=49.6335
# Sérsic 3: I_e=0.3023, r_e=48.8496, n=4.5129, x_0=58.5731
# Chi quadro minimo: 2800.570889831206
# False

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigma_i,
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')
# Out:
# Sérsic 1: I_e=99.9901, r_e=3.8184, n=0.7375, x_0=40.7200
# Sérsic 2: I_e=1.2666, r_e=49.9975, n=2.5022, x_0=49.6335
# Sérsic 3: I_e=0.3023, r_e=48.8496, n=4.5129, x_0=58.5731
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bounds = bounds_HA
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigma_i, *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigma_i, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[242], line 4
#       2 lower_bounds, upper_bounds = zip(*bounds)
#       3 bounds_list = (list(lower_bounds), list(upper_bounds))
# ----> 4 params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigma_i, *params), x_axes, radial_profile_continuum_2, p0=result.x,
#       5                                                              sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
#       6 print("Optimize parameters with curve fit:")
#       7 chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
#       8                                                                           real_errors_c2, sigma_i, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_minpack_py.py:1036, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1032 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#    1033                     **kwargs)
#    1035 if not res.success:
# -> 1036     raise RuntimeError("Optimal parameters not found: " + res.message)
#    1038 infodict = dict(nfev=res.nfev, fvec=res.fun)
#    1039 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6000)*(wv < 6500)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 190482.9523276417
# differential_evolution step 2: f(x)= 115397.3286824697
# differential_evolution step 3: f(x)= 69366.51589092238
# differential_evolution step 4: f(x)= 69366.51589092238
# differential_evolution step 5: f(x)= 69366.51589092238
# differential_evolution step 6: f(x)= 69366.51589092238
# differential_evolution step 7: f(x)= 52355.09931160753
# differential_evolution step 8: f(x)= 52355.09931160753
# differential_evolution step 9: f(x)= 52355.09931160753
# differential_evolution step 10: f(x)= 52355.09931160753
# differential_evolution step 11: f(x)= 15387.145754336838
# differential_evolution step 12: f(x)= 15387.145754336838
# differential_evolution step 13: f(x)= 15387.145754336838
# differential_evolution step 14: f(x)= 15387.145754336838
# differential_evolution step 15: f(x)= 15387.145754336838
# differential_evolution step 16: f(x)= 15387.145754336838
# differential_evolution step 17: f(x)= 15387.145754336838
# differential_evolution step 18: f(x)= 15387.145754336838
# differential_evolution step 19: f(x)= 15387.145754336838
# differential_evolution step 20: f(x)= 15387.145754336838
# differential_evolution step 21: f(x)= 15387.145754336838
# differential_evolution step 22: f(x)= 15387.145754336838
# differential_evolution step 23: f(x)= 15387.145754336838
# differential_evolution step 24: f(x)= 15387.145754336838
# differential_evolution step 25: f(x)= 15387.145754336838
# differential_evolution step 26: f(x)= 14346.016696006345
# differential_evolution step 27: f(x)= 14346.016696006345
# differential_evolution step 28: f(x)= 14058.593591125276
# differential_evolution step 29: f(x)= 14058.593591125276
# differential_evolution step 30: f(x)= 14058.593591125276
# differential_evolution step 31: f(x)= 13929.099324679286
# differential_evolution step 32: f(x)= 10841.255582121079
# differential_evolution step 33: f(x)= 10841.255582121079
# differential_evolution step 34: f(x)= 10841.255582121079
# differential_evolution step 35: f(x)= 10448.409518352208
# differential_evolution step 36: f(x)= 10448.409518352208
# differential_evolution step 37: f(x)= 10448.409518352208
# differential_evolution step 38: f(x)= 10448.409518352208
# differential_evolution step 39: f(x)= 9308.347361464992
# differential_evolution step 40: f(x)= 9308.347361464992
# differential_evolution step 41: f(x)= 9308.347361464992
# differential_evolution step 42: f(x)= 9308.347361464992
# differential_evolution step 43: f(x)= 9225.007132100156
# differential_evolution step 44: f(x)= 9175.833964689242
# differential_evolution step 45: f(x)= 9088.800719568164
# differential_evolution step 46: f(x)= 9088.800719568164
# differential_evolution step 47: f(x)= 8729.924164890159
# differential_evolution step 48: f(x)= 8729.924164890159
# differential_evolution step 49: f(x)= 8338.197165200474
# differential_evolution step 50: f(x)= 8338.197165200474
# differential_evolution step 51: f(x)= 8338.197165200474
# differential_evolution step 52: f(x)= 6723.623894152981
# differential_evolution step 53: f(x)= 6723.623894152981
# differential_evolution step 54: f(x)= 6723.623894152981
# differential_evolution step 55: f(x)= 6723.623894152981
# differential_evolution step 56: f(x)= 6723.623894152981
# differential_evolution step 57: f(x)= 6723.623894152981
# differential_evolution step 58: f(x)= 6723.623894152981
# differential_evolution step 59: f(x)= 6723.623894152981
# differential_evolution step 60: f(x)= 6723.623894152981
# differential_evolution step 61: f(x)= 6036.558064984108
# differential_evolution step 62: f(x)= 6036.558064984108
# differential_evolution step 63: f(x)= 5670.543995992602
# differential_evolution step 64: f(x)= 5670.543995992602
# differential_evolution step 65: f(x)= 5483.693770470966
# differential_evolution step 66: f(x)= 5483.693770470966
# differential_evolution step 67: f(x)= 5483.693770470966
# differential_evolution step 68: f(x)= 5483.693770470966
# differential_evolution step 69: f(x)= 5483.693770470966
# differential_evolution step 70: f(x)= 5483.693770470966
# differential_evolution step 71: f(x)= 5483.693770470966
# differential_evolution step 72: f(x)= 5483.693770470966
# differential_evolution step 73: f(x)= 5483.693770470966
# differential_evolution step 74: f(x)= 5483.693770470966
# differential_evolution step 75: f(x)= 5483.693770470966
# differential_evolution step 76: f(x)= 5483.693770470966
# differential_evolution step 77: f(x)= 5483.693770470966
# differential_evolution step 78: f(x)= 5483.693770470966
# differential_evolution step 79: f(x)= 5483.693770470966
# differential_evolution step 80: f(x)= 5483.693770470966
# differential_evolution step 81: f(x)= 5478.629924143136
# differential_evolution step 82: f(x)= 5478.629924143136
# differential_evolution step 83: f(x)= 5478.629924143136
# differential_evolution step 84: f(x)= 5478.629924143136
# differential_evolution step 85: f(x)= 5478.629924143136
# differential_evolution step 86: f(x)= 5478.629924143136
# differential_evolution step 87: f(x)= 5478.629924143136
# differential_evolution step 88: f(x)= 5414.189227667498
# differential_evolution step 89: f(x)= 5227.38861856928
# differential_evolution step 90: f(x)= 5227.38861856928
# differential_evolution step 91: f(x)= 5136.647986214146
# differential_evolution step 92: f(x)= 5136.647986214146
# differential_evolution step 93: f(x)= 5116.723480658881
# differential_evolution step 94: f(x)= 5116.723480658881
# differential_evolution step 95: f(x)= 5116.723480658881
# differential_evolution step 96: f(x)= 5116.723480658881
# differential_evolution step 97: f(x)= 5116.723480658881
# differential_evolution step 98: f(x)= 5116.723480658881
# differential_evolution step 99: f(x)= 5116.723480658881
# differential_evolution step 100: f(x)= 5116.723480658881
# differential_evolution step 101: f(x)= 5116.723480658881
# differential_evolution step 102: f(x)= 5116.723480658881
# differential_evolution step 103: f(x)= 5116.723480658881
# differential_evolution step 104: f(x)= 5017.855666567651
# differential_evolution step 105: f(x)= 5017.855666567651
# differential_evolution step 106: f(x)= 5017.855666567651
# differential_evolution step 107: f(x)= 4987.1832412580015
# differential_evolution step 108: f(x)= 4987.1832412580015
# differential_evolution step 109: f(x)= 4987.1832412580015
# differential_evolution step 110: f(x)= 4987.1832412580015
# differential_evolution step 111: f(x)= 4944.747134240647
# differential_evolution step 112: f(x)= 4944.747134240647
# differential_evolution step 113: f(x)= 4944.747134240647
# differential_evolution step 114: f(x)= 4944.747134240647
# differential_evolution step 115: f(x)= 4944.747134240647
# differential_evolution step 116: f(x)= 4944.747134240647
# differential_evolution step 117: f(x)= 4944.747134240647
# differential_evolution step 118: f(x)= 4944.747134240647
# differential_evolution step 119: f(x)= 4944.747134240647
# differential_evolution step 120: f(x)= 4944.747134240647
# differential_evolution step 121: f(x)= 4944.747134240647
# differential_evolution step 122: f(x)= 4944.747134240647
# differential_evolution step 123: f(x)= 4944.747134240647
# differential_evolution step 124: f(x)= 4944.747134240647
# differential_evolution step 125: f(x)= 4944.747134240647
# differential_evolution step 126: f(x)= 4944.747134240647
# differential_evolution step 127: f(x)= 4944.747134240647
# differential_evolution step 128: f(x)= 4900.101918894451
# differential_evolution step 129: f(x)= 4900.101918894451
# differential_evolution step 130: f(x)= 4900.101918894451
# differential_evolution step 131: f(x)= 4900.101918894451
# differential_evolution step 132: f(x)= 4900.101918894451
# differential_evolution step 133: f(x)= 4900.101918894451
# differential_evolution step 134: f(x)= 4900.101918894451
# differential_evolution step 135: f(x)= 4900.101918894451
# differential_evolution step 136: f(x)= 4900.101918894451
# differential_evolution step 137: f(x)= 4900.101918894451
# differential_evolution step 138: f(x)= 4900.101918894451
# differential_evolution step 139: f(x)= 4900.101918894451
# differential_evolution step 140: f(x)= 4900.101918894451
# differential_evolution step 141: f(x)= 4900.101918894451
# differential_evolution step 142: f(x)= 4900.101918894451
# differential_evolution step 143: f(x)= 4900.101918894451
# differential_evolution step 144: f(x)= 4900.101918894451
# differential_evolution step 145: f(x)= 4900.101918894451
# differential_evolution step 146: f(x)= 4900.101918894451
# differential_evolution step 147: f(x)= 4900.101918894451
# differential_evolution step 148: f(x)= 4900.101918894451
# differential_evolution step 149: f(x)= 4900.101918894451
# differential_evolution step 150: f(x)= 4875.284562598083
# differential_evolution step 151: f(x)= 4875.284562598083
# differential_evolution step 152: f(x)= 4875.284562598083
# differential_evolution step 153: f(x)= 4875.284562598083
# differential_evolution step 154: f(x)= 4875.284562598083
# differential_evolution step 155: f(x)= 4875.284562598083
# differential_evolution step 156: f(x)= 4859.607897340842
# differential_evolution step 157: f(x)= 4859.607897340842
# differential_evolution step 158: f(x)= 4859.607897340842
# differential_evolution step 159: f(x)= 4859.607897340842
# differential_evolution step 160: f(x)= 4859.607897340842
# differential_evolution step 161: f(x)= 4859.607897340842
# differential_evolution step 162: f(x)= 4859.607897340842
# differential_evolution step 163: f(x)= 4859.607897340842
# differential_evolution step 164: f(x)= 4858.38828363098
# differential_evolution step 165: f(x)= 4858.38828363098
# differential_evolution step 166: f(x)= 4851.689942559901
# differential_evolution step 167: f(x)= 4851.689942559901
# differential_evolution step 168: f(x)= 4851.689942559901
# differential_evolution step 169: f(x)= 4851.689942559901
# differential_evolution step 170: f(x)= 4851.689942559901
# differential_evolution step 171: f(x)= 4851.689942559901
# differential_evolution step 172: f(x)= 4851.451827607672
# differential_evolution step 173: f(x)= 4851.451827607672
# differential_evolution step 174: f(x)= 4851.451827607672
# differential_evolution step 175: f(x)= 4849.077107197312
# differential_evolution step 176: f(x)= 4831.578537406697
# differential_evolution step 177: f(x)= 4831.578537406697
# differential_evolution step 178: f(x)= 4831.578537406697
# differential_evolution step 179: f(x)= 4824.122254929742
# differential_evolution step 180: f(x)= 4816.342083722473
# differential_evolution step 181: f(x)= 4816.342083722473
# differential_evolution step 182: f(x)= 4813.850014854457
# differential_evolution step 183: f(x)= 4813.850014854457
# differential_evolution step 184: f(x)= 4813.850014854457
# differential_evolution step 185: f(x)= 4813.850014854457
# differential_evolution step 186: f(x)= 4813.850014854457
# differential_evolution step 187: f(x)= 4813.850014854457
# differential_evolution step 188: f(x)= 4813.850014854457
# differential_evolution step 189: f(x)= 4813.850014854457
# differential_evolution step 190: f(x)= 4813.850014854457
# differential_evolution step 191: f(x)= 4813.850014854457
# differential_evolution step 192: f(x)= 4813.850014854457
# differential_evolution step 193: f(x)= 4813.850014854457
# differential_evolution step 194: f(x)= 4811.690721542451
# differential_evolution step 195: f(x)= 4811.690721542451
# differential_evolution step 196: f(x)= 4811.690721542451
# differential_evolution step 197: f(x)= 4811.690721542451
# differential_evolution step 198: f(x)= 4811.690721542451
# differential_evolution step 199: f(x)= 4811.690721542451
# differential_evolution step 200: f(x)= 4811.690721542451
# differential_evolution step 201: f(x)= 4811.690721542451
# differential_evolution step 202: f(x)= 4811.690721542451
# differential_evolution step 203: f(x)= 4811.690721542451
# differential_evolution step 204: f(x)= 4811.690721542451
# differential_evolution step 205: f(x)= 4807.370188064441
# differential_evolution step 206: f(x)= 4807.370188064441
# differential_evolution step 207: f(x)= 4807.370188064441
# differential_evolution step 208: f(x)= 4807.370188064441
# differential_evolution step 209: f(x)= 4807.370188064441
# differential_evolution step 210: f(x)= 4798.479352956841
# differential_evolution step 211: f(x)= 4798.479352956841
# differential_evolution step 212: f(x)= 4796.102433917773
# differential_evolution step 213: f(x)= 4796.102433917773
# differential_evolution step 214: f(x)= 4794.734201414498
# differential_evolution step 215: f(x)= 4792.864446113352
# differential_evolution step 216: f(x)= 4787.917493367671
# differential_evolution step 217: f(x)= 4787.912017128757
# differential_evolution step 218: f(x)= 4784.595923472202
# differential_evolution step 219: f(x)= 4784.595923472202
# differential_evolution step 220: f(x)= 4784.595923472202
# differential_evolution step 221: f(x)= 4784.595923472202
# differential_evolution step 222: f(x)= 4784.595923472202
# differential_evolution step 223: f(x)= 4784.595923472202
# differential_evolution step 224: f(x)= 4784.595923472202
# differential_evolution step 225: f(x)= 4784.595923472202
# differential_evolution step 226: f(x)= 4784.595923472202
# differential_evolution step 227: f(x)= 4784.595923472202
# differential_evolution step 228: f(x)= 4783.7436226495465
# differential_evolution step 229: f(x)= 4780.990971883858
# differential_evolution step 230: f(x)= 4780.990971883858
# differential_evolution step 231: f(x)= 4777.7769632955415
# differential_evolution step 232: f(x)= 4774.450566497312
# differential_evolution step 233: f(x)= 4770.553279257565
# differential_evolution step 234: f(x)= 4770.553279257565
# differential_evolution step 235: f(x)= 4770.553279257565
# differential_evolution step 236: f(x)= 4764.7642554909935
# differential_evolution step 237: f(x)= 4764.7642554909935
# differential_evolution step 238: f(x)= 4764.7642554909935
# differential_evolution step 239: f(x)= 4764.7642554909935
# differential_evolution step 240: f(x)= 4764.7642554909935
# differential_evolution step 241: f(x)= 4764.7642554909935
# differential_evolution step 242: f(x)= 4764.7642554909935
# differential_evolution step 243: f(x)= 4756.822042544239
# differential_evolution step 244: f(x)= 4756.822042544239
# differential_evolution step 245: f(x)= 4756.822042544239
# differential_evolution step 246: f(x)= 4756.822042544239
# differential_evolution step 247: f(x)= 4756.822042544239
# differential_evolution step 248: f(x)= 4756.822042544239
# differential_evolution step 249: f(x)= 4756.822042544239
# differential_evolution step 250: f(x)= 4756.822042544239
# differential_evolution step 251: f(x)= 4756.822042544239
# differential_evolution step 252: f(x)= 4756.822042544239
# differential_evolution step 253: f(x)= 4756.822042544239
# differential_evolution step 254: f(x)= 4756.822042544239
# differential_evolution step 255: f(x)= 4756.822042544239
# differential_evolution step 256: f(x)= 4756.822042544239
# differential_evolution step 257: f(x)= 4756.822042544239
# differential_evolution step 258: f(x)= 4756.822042544239
# differential_evolution step 259: f(x)= 4756.822042544239
# differential_evolution step 260: f(x)= 4756.822042544239
# differential_evolution step 261: f(x)= 4756.822042544239
# differential_evolution step 262: f(x)= 4755.216593625954
# differential_evolution step 263: f(x)= 4755.216593625954
# differential_evolution step 264: f(x)= 4755.216593625954
# differential_evolution step 265: f(x)= 4755.216593625954
# differential_evolution step 266: f(x)= 4755.216593625954
# differential_evolution step 267: f(x)= 4755.216593625954
# differential_evolution step 268: f(x)= 4755.216593625954
# differential_evolution step 269: f(x)= 4755.216593625954
# differential_evolution step 270: f(x)= 4755.216593625954
# differential_evolution step 271: f(x)= 4754.9185671823425
# differential_evolution step 272: f(x)= 4754.9185671823425
# differential_evolution step 273: f(x)= 4751.6118472933495
# differential_evolution step 274: f(x)= 4751.6118472933495
# differential_evolution step 275: f(x)= 4751.6118472933495
# differential_evolution step 276: f(x)= 4751.6118472933495
# differential_evolution step 277: f(x)= 4751.6118472933495
# differential_evolution step 278: f(x)= 4751.6118472933495
# differential_evolution step 279: f(x)= 4745.22923035647
# differential_evolution step 280: f(x)= 4745.22923035647
# differential_evolution step 281: f(x)= 4745.22923035647
# differential_evolution step 282: f(x)= 4745.22923035647
# differential_evolution step 283: f(x)= 4745.22923035647
# differential_evolution step 284: f(x)= 4745.22923035647
# differential_evolution step 285: f(x)= 4745.22923035647
# differential_evolution step 286: f(x)= 4745.22923035647
# differential_evolution step 287: f(x)= 4745.22923035647
# differential_evolution step 288: f(x)= 4742.523189016368
# differential_evolution step 289: f(x)= 4738.924344888181
# differential_evolution step 290: f(x)= 4738.924344888181
# differential_evolution step 291: f(x)= 4738.924344888181
# differential_evolution step 292: f(x)= 4738.924344888181
# differential_evolution step 293: f(x)= 4738.924344888181
# differential_evolution step 294: f(x)= 4738.924344888181
# differential_evolution step 295: f(x)= 4738.924344888181
# differential_evolution step 296: f(x)= 4738.924344888181
# differential_evolution step 297: f(x)= 4738.924344888181
# differential_evolution step 298: f(x)= 4738.924344888181
# differential_evolution step 299: f(x)= 4738.924344888181
# differential_evolution step 300: f(x)= 4738.924344888181
# differential_evolution step 301: f(x)= 4738.924344888181
# differential_evolution step 302: f(x)= 4738.924344888181
# differential_evolution step 303: f(x)= 4738.924344888181
# differential_evolution step 304: f(x)= 4738.924344888181
# differential_evolution step 305: f(x)= 4738.924344888181
# differential_evolution step 306: f(x)= 4738.924344888181
# differential_evolution step 307: f(x)= 4737.961930883964
# differential_evolution step 308: f(x)= 4737.804226150815
# differential_evolution step 309: f(x)= 4734.119654626898
# differential_evolution step 310: f(x)= 4734.119654626898
# differential_evolution step 311: f(x)= 4734.119654626898
# differential_evolution step 312: f(x)= 4734.119654626898
# differential_evolution step 313: f(x)= 4734.119654626898
# differential_evolution step 314: f(x)= 4731.659667102756
# differential_evolution step 315: f(x)= 4731.659667102756
# differential_evolution step 316: f(x)= 4731.659667102756
# differential_evolution step 317: f(x)= 4731.659667102756
# differential_evolution step 318: f(x)= 4731.659667102756
# differential_evolution step 319: f(x)= 4731.659667102756
# differential_evolution step 320: f(x)= 4730.310715284856
# differential_evolution step 321: f(x)= 4730.310715284856
# differential_evolution step 322: f(x)= 4728.991280993659
# differential_evolution step 323: f(x)= 4728.991280993659
# differential_evolution step 324: f(x)= 4728.991280993659
# differential_evolution step 325: f(x)= 4728.991280993659
# differential_evolution step 326: f(x)= 4728.991280993659
# differential_evolution step 327: f(x)= 4728.991280993659
# differential_evolution step 328: f(x)= 4728.991280993659
# differential_evolution step 329: f(x)= 4728.991280993659
# differential_evolution step 330: f(x)= 4728.991280993659
# differential_evolution step 331: f(x)= 4728.571994948562
# differential_evolution step 332: f(x)= 4726.856874622525
# differential_evolution step 333: f(x)= 4726.856874622525
# differential_evolution step 334: f(x)= 4726.856874622525
# differential_evolution step 335: f(x)= 4726.507648618343
# differential_evolution step 336: f(x)= 4726.507648618343
# differential_evolution step 337: f(x)= 4726.507648618343
# differential_evolution step 338: f(x)= 4726.507648618343
# differential_evolution step 339: f(x)= 4725.451587504842
# differential_evolution step 340: f(x)= 4725.350468559984
# differential_evolution step 341: f(x)= 4725.350468559984
# differential_evolution step 342: f(x)= 4725.350468559984
# differential_evolution step 343: f(x)= 4723.472320233703
# differential_evolution step 344: f(x)= 4723.472320233703
# differential_evolution step 345: f(x)= 4723.301181164012
# differential_evolution step 346: f(x)= 4723.301181164012
# differential_evolution step 347: f(x)= 4723.301181164012
# differential_evolution step 348: f(x)= 4721.394258041385
# differential_evolution step 349: f(x)= 4721.394258041385
# differential_evolution step 350: f(x)= 4721.394258041385
# differential_evolution step 351: f(x)= 4721.394258041385
# differential_evolution step 352: f(x)= 4721.394258041385
# differential_evolution step 353: f(x)= 4721.394258041385
# differential_evolution step 354: f(x)= 4721.394258041385
# differential_evolution step 355: f(x)= 4721.35986756791
# differential_evolution step 356: f(x)= 4721.35986756791
# differential_evolution step 357: f(x)= 4721.35986756791
# differential_evolution step 358: f(x)= 4721.35986756791
# differential_evolution step 359: f(x)= 4721.35986756791
# differential_evolution step 360: f(x)= 4721.35986756791
# differential_evolution step 361: f(x)= 4721.35986756791
# differential_evolution step 362: f(x)= 4721.35986756791
# differential_evolution step 363: f(x)= 4721.35986756791
# differential_evolution step 364: f(x)= 4721.35986756791
# differential_evolution step 365: f(x)= 4721.35986756791
# differential_evolution step 366: f(x)= 4721.35986756791
# differential_evolution step 367: f(x)= 4721.35986756791
# differential_evolution step 368: f(x)= 4721.35986756791
# differential_evolution step 369: f(x)= 4720.897211059787
# differential_evolution step 370: f(x)= 4720.897211059787
# differential_evolution step 371: f(x)= 4720.897211059787
# differential_evolution step 372: f(x)= 4720.897211059787
# differential_evolution step 373: f(x)= 4720.897211059787
# differential_evolution step 374: f(x)= 4720.897211059787
# differential_evolution step 375: f(x)= 4720.897211059787
# differential_evolution step 376: f(x)= 4720.897211059787
# differential_evolution step 377: f(x)= 4720.859236766187
# differential_evolution step 378: f(x)= 4720.859236766187
# differential_evolution step 379: f(x)= 4720.8090183829945
# differential_evolution step 380: f(x)= 4720.313118391681
# differential_evolution step 381: f(x)= 4720.114899241333
# differential_evolution step 382: f(x)= 4720.114899241333
# differential_evolution step 383: f(x)= 4720.114899241333
# differential_evolution step 384: f(x)= 4720.114899241333
# differential_evolution step 385: f(x)= 4720.114899241333
# differential_evolution step 386: f(x)= 4720.114899241333
# differential_evolution step 387: f(x)= 4720.114899241333
# differential_evolution step 388: f(x)= 4719.947727698242
# differential_evolution step 389: f(x)= 4719.947727698242
# differential_evolution step 390: f(x)= 4719.947727698242
# differential_evolution step 391: f(x)= 4719.947727698242
# differential_evolution step 392: f(x)= 4719.90780403453
# differential_evolution step 393: f(x)= 4719.90780403453
# differential_evolution step 394: f(x)= 4719.90780403453
# differential_evolution step 395: f(x)= 4719.90780403453
# differential_evolution step 396: f(x)= 4719.90780403453
# differential_evolution step 397: f(x)= 4719.876214135473
# differential_evolution step 398: f(x)= 4719.876214135473
# differential_evolution step 399: f(x)= 4719.876214135473
# differential_evolution step 400: f(x)= 4719.876214135473
# differential_evolution step 401: f(x)= 4719.876214135473
# differential_evolution step 402: f(x)= 4719.876214135473
# differential_evolution step 403: f(x)= 4719.876214135473
# differential_evolution step 404: f(x)= 4719.876214135473
# differential_evolution step 405: f(x)= 4719.876214135473
# differential_evolution step 406: f(x)= 4719.876214135473
# differential_evolution step 407: f(x)= 4719.876214135473
# differential_evolution step 408: f(x)= 4719.826536100091
# differential_evolution step 409: f(x)= 4719.826536100091
# differential_evolution step 410: f(x)= 4719.7573044667715
# differential_evolution step 411: f(x)= 4719.7573044667715
# differential_evolution step 412: f(x)= 4719.7573044667715
# differential_evolution step 413: f(x)= 4719.7573044667715
# differential_evolution step 414: f(x)= 4719.7573044667715
# differential_evolution step 415: f(x)= 4719.755653096337
# differential_evolution step 416: f(x)= 4719.755653096337
# differential_evolution step 417: f(x)= 4719.755653096337
# differential_evolution step 418: f(x)= 4719.755653096337
# differential_evolution step 419: f(x)= 4719.755653096337
# differential_evolution step 420: f(x)= 4719.755653096337
# differential_evolution step 421: f(x)= 4719.755653096337
# differential_evolution step 422: f(x)= 4719.755653096337
# differential_evolution step 423: f(x)= 4719.755653096337
# differential_evolution step 424: f(x)= 4719.755653096337
# differential_evolution step 425: f(x)= 4719.755653096337
# differential_evolution step 426: f(x)= 4719.755653096337
# differential_evolution step 427: f(x)= 4719.755653096337
# differential_evolution step 428: f(x)= 4719.755653096337
# differential_evolution step 429: f(x)= 4719.729018992872
# differential_evolution step 430: f(x)= 4719.729018992872
# differential_evolution step 431: f(x)= 4719.729018992872
# differential_evolution step 432: f(x)= 4719.729018992872
# differential_evolution step 433: f(x)= 4719.727451078395
# differential_evolution step 434: f(x)= 4719.727451078395
# differential_evolution step 435: f(x)= 4719.727451078395
# differential_evolution step 436: f(x)= 4719.727451078395
# differential_evolution step 437: f(x)= 4719.727451078395
# differential_evolution step 438: f(x)= 4719.706792686505
# differential_evolution step 439: f(x)= 4719.692975626277
# differential_evolution step 440: f(x)= 4719.692975626277
# differential_evolution step 441: f(x)= 4719.692975626277
# differential_evolution step 442: f(x)= 4719.692975626277
# differential_evolution step 443: f(x)= 4719.6823581199715
# differential_evolution step 444: f(x)= 4719.6823581199715
# differential_evolution step 445: f(x)= 4719.6823581199715
# differential_evolution step 446: f(x)= 4719.6749659710895
# differential_evolution step 447: f(x)= 4719.6749659710895
# differential_evolution step 448: f(x)= 4719.6749659710895
# differential_evolution step 449: f(x)= 4719.6749659710895
# differential_evolution step 450: f(x)= 4719.6749659710895
# differential_evolution step 451: f(x)= 4719.6749659710895
# differential_evolution step 452: f(x)= 4719.6749659710895
# differential_evolution step 453: f(x)= 4719.673963045398
# differential_evolution step 454: f(x)= 4719.673963045398
# differential_evolution step 455: f(x)= 4719.658777465999
# differential_evolution step 456: f(x)= 4719.658777465999
# differential_evolution step 457: f(x)= 4719.658777465999
# differential_evolution step 458: f(x)= 4719.642118138808
# differential_evolution step 459: f(x)= 4719.642118138808
# differential_evolution step 460: f(x)= 4719.642118138808
# differential_evolution step 461: f(x)= 4719.633026251282
# differential_evolution step 462: f(x)= 4719.633026251282
# differential_evolution step 463: f(x)= 4719.633026251282
# differential_evolution step 464: f(x)= 4719.633026251282
# differential_evolution step 465: f(x)= 4719.633026251282
# differential_evolution step 466: f(x)= 4719.633026251282
# differential_evolution step 467: f(x)= 4719.633026251282
# differential_evolution step 468: f(x)= 4719.633026251282
# differential_evolution step 469: f(x)= 4719.633026251282
# differential_evolution step 470: f(x)= 4719.633026251282
# differential_evolution step 471: f(x)= 4719.633026251282
# differential_evolution step 472: f(x)= 4719.633026251282
# differential_evolution step 473: f(x)= 4719.633026251282
# differential_evolution step 474: f(x)= 4719.633026251282
# differential_evolution step 475: f(x)= 4719.633026251282
# differential_evolution step 476: f(x)= 4719.633026251282
# differential_evolution step 477: f(x)= 4719.633026251282
# differential_evolution step 478: f(x)= 4719.633026251282
# differential_evolution step 479: f(x)= 4719.632347821892
# differential_evolution step 480: f(x)= 4719.631422630507
# differential_evolution step 481: f(x)= 4719.628097653905
# differential_evolution step 482: f(x)= 4719.628097653905
# differential_evolution step 483: f(x)= 4719.628097653905
# differential_evolution step 484: f(x)= 4719.626645384816
# differential_evolution step 485: f(x)= 4719.626645384816
# differential_evolution step 486: f(x)= 4719.626645384816
# differential_evolution step 487: f(x)= 4719.626645384816
# differential_evolution step 488: f(x)= 4719.624073021648
# differential_evolution step 489: f(x)= 4719.621603590596
# differential_evolution step 490: f(x)= 4719.621603590596
# differential_evolution step 491: f(x)= 4719.621603590596
# differential_evolution step 492: f(x)= 4719.621603590596
# differential_evolution step 493: f(x)= 4719.621603590596
# differential_evolution step 494: f(x)= 4719.621603590596
# differential_evolution step 495: f(x)= 4719.621603590596
# differential_evolution step 496: f(x)= 4719.621603590596
# differential_evolution step 497: f(x)= 4719.621603590596
# differential_evolution step 498: f(x)= 4719.621603590596
# differential_evolution step 499: f(x)= 4719.621603590596
# differential_evolution step 500: f(x)= 4719.621603590596
# differential_evolution step 501: f(x)= 4719.621603590596
# differential_evolution step 502: f(x)= 4719.614963527271
# differential_evolution step 503: f(x)= 4719.614963527271
# differential_evolution step 504: f(x)= 4719.614963527271
# differential_evolution step 505: f(x)= 4719.614963527271
# differential_evolution step 506: f(x)= 4719.614963527271
# differential_evolution step 507: f(x)= 4719.614963527271
# differential_evolution step 508: f(x)= 4719.614963527271
# differential_evolution step 509: f(x)= 4719.614963527271
# differential_evolution step 510: f(x)= 4719.614963527271
# differential_evolution step 511: f(x)= 4719.614963527271
# differential_evolution step 512: f(x)= 4719.614963527271
# differential_evolution step 513: f(x)= 4719.614963527271
# differential_evolution step 514: f(x)= 4719.613442627839
# differential_evolution step 515: f(x)= 4719.613442627839
# differential_evolution step 516: f(x)= 4719.613442627839
# differential_evolution step 517: f(x)= 4719.613442627839
# differential_evolution step 518: f(x)= 4719.613442627839
# differential_evolution step 519: f(x)= 4719.613442627839
# differential_evolution step 520: f(x)= 4719.611745284814
# differential_evolution step 521: f(x)= 4719.611745284814
# differential_evolution step 522: f(x)= 4719.611745284814
# differential_evolution step 523: f(x)= 4719.611745284814
# differential_evolution step 524: f(x)= 4719.611745284814
# differential_evolution step 525: f(x)= 4719.611745284814
# differential_evolution step 526: f(x)= 4719.611745284814
# differential_evolution step 527: f(x)= 4719.611745284814
# differential_evolution step 528: f(x)= 4719.611745284814
# differential_evolution step 529: f(x)= 4719.611745284814
# differential_evolution step 530: f(x)= 4719.611745284814
# differential_evolution step 531: f(x)= 4719.611745284814
# differential_evolution step 532: f(x)= 4719.611745284814
# differential_evolution step 533: f(x)= 4719.611002640743
# differential_evolution step 534: f(x)= 4719.611002640743
# differential_evolution step 535: f(x)= 4719.611002640743
# differential_evolution step 536: f(x)= 4719.61032221587
# differential_evolution step 537: f(x)= 4719.61032221587
# differential_evolution step 538: f(x)= 4719.61032221587
# differential_evolution step 539: f(x)= 4719.61032221587
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=100.0000, r_e=3.9661, n=0.6928, x_0=40.6212
# Sérsic 2: I_e=1.2401, r_e=49.9990, n=2.3819, x_0=49.4844
# Sérsic 3: I_e=11.6243, r_e=4.4131, n=1.3811, x_0=58.1839
# Chi quadro minimo: 4719.609297448933
# True

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')
# Out:
# Sérsic 1: I_e=100.0000, r_e=3.9661, n=0.6928, x_0=40.6212
# Sérsic 2: I_e=1.2401, r_e=49.9990, n=2.3819, x_0=49.4844
# Sérsic 3: I_e=11.6243, r_e=4.4131, n=1.3811, x_0=58.1839
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bounds_HA = [
    (0, 100),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 43),   # x_0: posizione da 0 a 100

    (0, 20),
    (0, 50),
    (0.1, 10),
    (46, 50),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (54, 61)
]
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3, bounds = bounds_list, maxfev = 10000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=99.9999, r_e=3.3629, n=0.6422, x_0=40.4990
# Sérsic 2: I_e=1.5820, r_e=50.0000, n=2.3556, x_0=48.4885
# Sérsic 3: I_e=14.2605, r_e=3.7038, n=1.2106, x_0=58.1709
# [ 9.68499204  0.15376728  0.07910439  0.16234586  0.72452092 14.32193572
#   0.33382921  0.31408971  4.3007767   0.70477835  0.26304621  0.1621756 ]
# 12.18130777118488

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d1 = {'Name': ['Continuum 3'], 'Chi squared': chi2_continuum_3,
      'Dof': dof_continuum_3, 'Chi reduced': chi2_reduced_continuum_3}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_continuum_3.csv", index= False)

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)
