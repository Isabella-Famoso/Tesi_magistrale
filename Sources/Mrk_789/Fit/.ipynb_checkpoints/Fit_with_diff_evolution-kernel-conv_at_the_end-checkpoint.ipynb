# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32

# %%
image_cut = image[75:175, 0:1890]
image_error_cut = image_error[75:175, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.03144
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/PSF/Real_seeing_Mrk789.txt")
sigmas = seeing / 2.35
n_component = 3
print(sigmas)
# Out:
# [0.81079758 0.94529828 0.80761288 0.78693189 0.94913518 0.84425532]

# %%
l_HA
# Out:
# 6769.340719999999

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[75:175, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 24)*(y < 34)
mask_wv = wv > 4451
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 45),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 54),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (54, 65)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 14772.246588382533
# differential_evolution step 2: f(x)= 14772.246588382533
# differential_evolution step 3: f(x)= 9991.058835240729
# differential_evolution step 4: f(x)= 9991.058835240729
# differential_evolution step 5: f(x)= 3733.5259671131917
# differential_evolution step 6: f(x)= 3733.5259671131917
# differential_evolution step 7: f(x)= 3733.5259671131917
# differential_evolution step 8: f(x)= 3733.5259671131917
# differential_evolution step 9: f(x)= 3733.5259671131917
# differential_evolution step 10: f(x)= 2176.669931792296
# differential_evolution step 11: f(x)= 2176.669931792296
# differential_evolution step 12: f(x)= 2176.669931792296
# differential_evolution step 13: f(x)= 2051.205270268303
# differential_evolution step 14: f(x)= 1887.8439547025102
# differential_evolution step 15: f(x)= 1887.8439547025102
# differential_evolution step 16: f(x)= 1887.8439547025102
# differential_evolution step 17: f(x)= 1887.8439547025102
# differential_evolution step 18: f(x)= 1887.8439547025102
# differential_evolution step 19: f(x)= 1887.8439547025102
# differential_evolution step 20: f(x)= 1887.8439547025102
# differential_evolution step 21: f(x)= 1887.8439547025102
# differential_evolution step 22: f(x)= 1808.2701703800806
# differential_evolution step 23: f(x)= 1808.2701703800806
# differential_evolution step 24: f(x)= 1740.6568838302214
# differential_evolution step 25: f(x)= 1740.6568838302214
# differential_evolution step 26: f(x)= 1740.6568838302214
# differential_evolution step 27: f(x)= 1740.6568838302214
# differential_evolution step 28: f(x)= 1740.6568838302214
# differential_evolution step 29: f(x)= 1640.3631671606433
# differential_evolution step 30: f(x)= 1204.8862497030696
# differential_evolution step 31: f(x)= 1204.8862497030696
# differential_evolution step 32: f(x)= 1100.9032973573612
# differential_evolution step 33: f(x)= 1100.9032973573612
# differential_evolution step 34: f(x)= 1100.9032973573612
# differential_evolution step 35: f(x)= 1040.5446361121187
# differential_evolution step 36: f(x)= 1040.5446361121187
# differential_evolution step 37: f(x)= 1040.5446361121187
# differential_evolution step 38: f(x)= 1040.5446361121187
# differential_evolution step 39: f(x)= 1040.5446361121187
# differential_evolution step 40: f(x)= 1040.5446361121187
# differential_evolution step 41: f(x)= 1040.5446361121187
# differential_evolution step 42: f(x)= 1040.5446361121187
# differential_evolution step 43: f(x)= 996.9930825956865
# differential_evolution step 44: f(x)= 996.9930825956865
# differential_evolution step 45: f(x)= 996.9930825956865
# differential_evolution step 46: f(x)= 925.7878444174305
# differential_evolution step 47: f(x)= 925.7878444174305
# differential_evolution step 48: f(x)= 925.7878444174305
# differential_evolution step 49: f(x)= 925.7878444174305
# differential_evolution step 50: f(x)= 875.1780572780362
# differential_evolution step 51: f(x)= 875.1780572780362
# differential_evolution step 52: f(x)= 799.062073531302
# differential_evolution step 53: f(x)= 799.062073531302
# differential_evolution step 54: f(x)= 642.2177968723895
# differential_evolution step 55: f(x)= 642.2177968723895
# differential_evolution step 56: f(x)= 568.6862915775099
# differential_evolution step 57: f(x)= 568.6862915775099
# differential_evolution step 58: f(x)= 568.6862915775099
# differential_evolution step 59: f(x)= 568.6862915775099
# differential_evolution step 60: f(x)= 568.6862915775099
# differential_evolution step 61: f(x)= 568.6862915775099
# differential_evolution step 62: f(x)= 568.6862915775099
# differential_evolution step 63: f(x)= 568.6862915775099
# differential_evolution step 64: f(x)= 568.6862915775099
# differential_evolution step 65: f(x)= 568.6862915775099
# differential_evolution step 66: f(x)= 568.6862915775099
# differential_evolution step 67: f(x)= 568.6862915775099
# differential_evolution step 68: f(x)= 568.6862915775099
# differential_evolution step 69: f(x)= 561.955784647939
# differential_evolution step 70: f(x)= 561.955784647939
# differential_evolution step 71: f(x)= 561.955784647939
# differential_evolution step 72: f(x)= 475.41697896925996
# differential_evolution step 73: f(x)= 475.41697896925996
# differential_evolution step 74: f(x)= 475.41697896925996
# differential_evolution step 75: f(x)= 475.41697896925996
# differential_evolution step 76: f(x)= 475.41697896925996
# differential_evolution step 77: f(x)= 475.41697896925996
# differential_evolution step 78: f(x)= 475.41697896925996
# differential_evolution step 79: f(x)= 475.41697896925996
# differential_evolution step 80: f(x)= 475.41697896925996
# differential_evolution step 81: f(x)= 475.41697896925996
# differential_evolution step 82: f(x)= 475.41697896925996
# differential_evolution step 83: f(x)= 475.41697896925996
# differential_evolution step 84: f(x)= 475.41697896925996
# differential_evolution step 85: f(x)= 475.41697896925996
# differential_evolution step 86: f(x)= 475.41697896925996
# differential_evolution step 87: f(x)= 475.41697896925996
# differential_evolution step 88: f(x)= 475.41697896925996
# differential_evolution step 89: f(x)= 475.41697896925996
# differential_evolution step 90: f(x)= 475.41697896925996
# differential_evolution step 91: f(x)= 474.33242902419335
# differential_evolution step 92: f(x)= 474.33242902419335
# differential_evolution step 93: f(x)= 474.04963250148546
# differential_evolution step 94: f(x)= 473.9028440470145
# differential_evolution step 95: f(x)= 469.86735685666605
# differential_evolution step 96: f(x)= 462.681611955571
# differential_evolution step 97: f(x)= 462.681611955571
# differential_evolution step 98: f(x)= 460.280506157728
# differential_evolution step 99: f(x)= 452.7015102088719
# differential_evolution step 100: f(x)= 452.7015102088719
# differential_evolution step 101: f(x)= 452.62714194155757
# differential_evolution step 102: f(x)= 450.2556822388925
# differential_evolution step 103: f(x)= 450.2556822388925
# differential_evolution step 104: f(x)= 449.7600888747977
# differential_evolution step 105: f(x)= 449.7600888747977
# differential_evolution step 106: f(x)= 449.7600888747977
# differential_evolution step 107: f(x)= 445.3387180859941
# differential_evolution step 108: f(x)= 445.3387180859941
# differential_evolution step 109: f(x)= 445.3387180859941
# differential_evolution step 110: f(x)= 445.3387180859941
# differential_evolution step 111: f(x)= 444.6448998812329
# differential_evolution step 112: f(x)= 444.30379921650933
# differential_evolution step 113: f(x)= 444.30379921650933
# differential_evolution step 114: f(x)= 444.30379921650933
# differential_evolution step 115: f(x)= 443.2343379599226
# differential_evolution step 116: f(x)= 443.2343379599226
# differential_evolution step 117: f(x)= 443.2343379599226
# differential_evolution step 118: f(x)= 443.2343379599226
# differential_evolution step 119: f(x)= 438.9211785066253
# differential_evolution step 120: f(x)= 438.9211785066253
# differential_evolution step 121: f(x)= 438.9211785066253
# differential_evolution step 122: f(x)= 438.9211785066253
# differential_evolution step 123: f(x)= 438.9211785066253
# differential_evolution step 124: f(x)= 438.9211785066253
# differential_evolution step 125: f(x)= 438.9211785066253
# differential_evolution step 126: f(x)= 438.9211785066253
# differential_evolution step 127: f(x)= 438.9211785066253
# differential_evolution step 128: f(x)= 438.9211785066253
# differential_evolution step 129: f(x)= 438.9211785066253
# differential_evolution step 130: f(x)= 438.9211785066253
# differential_evolution step 131: f(x)= 436.52905633262424
# differential_evolution step 132: f(x)= 436.52905633262424
# differential_evolution step 133: f(x)= 436.52905633262424
# differential_evolution step 134: f(x)= 436.52905633262424
# differential_evolution step 135: f(x)= 436.52905633262424
# differential_evolution step 136: f(x)= 436.52905633262424
# differential_evolution step 137: f(x)= 436.52905633262424
# differential_evolution step 138: f(x)= 436.52905633262424
# differential_evolution step 139: f(x)= 436.52905633262424
# differential_evolution step 140: f(x)= 436.52905633262424
# differential_evolution step 141: f(x)= 436.52905633262424
# differential_evolution step 142: f(x)= 436.52905633262424
# differential_evolution step 143: f(x)= 436.52905633262424
# differential_evolution step 144: f(x)= 436.52905633262424
# differential_evolution step 145: f(x)= 436.52905633262424
# differential_evolution step 146: f(x)= 436.52905633262424
# differential_evolution step 147: f(x)= 436.52905633262424
# differential_evolution step 148: f(x)= 436.5252954268965
# differential_evolution step 149: f(x)= 436.4687327617561
# differential_evolution step 150: f(x)= 436.3965087006873
# differential_evolution step 151: f(x)= 436.3965087006873
# differential_evolution step 152: f(x)= 436.3965087006873
# differential_evolution step 153: f(x)= 436.1244669418962
# differential_evolution step 154: f(x)= 435.87177324950505
# differential_evolution step 155: f(x)= 435.7836894100469
# differential_evolution step 156: f(x)= 435.7836894100469
# differential_evolution step 157: f(x)= 435.4108656469573
# differential_evolution step 158: f(x)= 435.4108656469573
# differential_evolution step 159: f(x)= 435.4108656469573
# differential_evolution step 160: f(x)= 435.4108656469573
# differential_evolution step 161: f(x)= 435.4108656469573
# differential_evolution step 162: f(x)= 435.2428765030638
# differential_evolution step 163: f(x)= 435.2428765030638
# differential_evolution step 164: f(x)= 435.2428765030638
# differential_evolution step 165: f(x)= 435.1686271506789
# differential_evolution step 166: f(x)= 435.1686271506789
# differential_evolution step 167: f(x)= 435.1686271506789
# differential_evolution step 168: f(x)= 435.1686271506789
# differential_evolution step 169: f(x)= 435.1686271506789
# differential_evolution step 170: f(x)= 435.0880808071937
# differential_evolution step 171: f(x)= 435.0880808071937
# differential_evolution step 172: f(x)= 435.0880808071937
# differential_evolution step 173: f(x)= 435.0880808071937
# differential_evolution step 174: f(x)= 435.0880808071937
# differential_evolution step 175: f(x)= 435.0880808071937
# differential_evolution step 176: f(x)= 435.0880808071937
# differential_evolution step 177: f(x)= 435.014632079068
# differential_evolution step 178: f(x)= 435.014632079068
# differential_evolution step 179: f(x)= 435.014632079068
# differential_evolution step 180: f(x)= 435.014632079068
# differential_evolution step 181: f(x)= 434.9764967362368
# differential_evolution step 182: f(x)= 434.9764967362368
# differential_evolution step 183: f(x)= 434.9764967362368
# differential_evolution step 184: f(x)= 434.9764967362368
# differential_evolution step 185: f(x)= 434.9764967362368
# differential_evolution step 186: f(x)= 434.9764967362368
# differential_evolution step 187: f(x)= 434.97327574569033
# differential_evolution step 188: f(x)= 434.92662828453786
# differential_evolution step 189: f(x)= 434.92662828453786
# differential_evolution step 190: f(x)= 434.92662828453786
# differential_evolution step 191: f(x)= 434.92662828453786
# differential_evolution step 192: f(x)= 434.92662828453786
# differential_evolution step 193: f(x)= 434.92662828453786
# differential_evolution step 194: f(x)= 434.8507184045342
# differential_evolution step 195: f(x)= 434.8507184045342
# differential_evolution step 196: f(x)= 434.8507184045342
# differential_evolution step 197: f(x)= 434.8507184045342
# differential_evolution step 198: f(x)= 434.8507184045342
# differential_evolution step 199: f(x)= 434.7841360074269
# differential_evolution step 200: f(x)= 434.7841360074269
# differential_evolution step 201: f(x)= 434.7835157234585
# differential_evolution step 202: f(x)= 434.7835157234585
# differential_evolution step 203: f(x)= 434.7835157234585
# differential_evolution step 204: f(x)= 434.7835157234585
# differential_evolution step 205: f(x)= 434.7835157234585
# differential_evolution step 206: f(x)= 434.7304222249549
# differential_evolution step 207: f(x)= 434.70665717672216
# differential_evolution step 208: f(x)= 434.70665717672216
# differential_evolution step 209: f(x)= 434.70113486009916
# differential_evolution step 210: f(x)= 434.70113486009916
# differential_evolution step 211: f(x)= 434.70113486009916
# differential_evolution step 212: f(x)= 434.65871553233535
# differential_evolution step 213: f(x)= 434.65871553233535
# differential_evolution step 214: f(x)= 434.65871553233535
# differential_evolution step 215: f(x)= 434.65871553233535
# differential_evolution step 216: f(x)= 434.642984952078
# differential_evolution step 217: f(x)= 434.642984952078
# differential_evolution step 218: f(x)= 434.6200277824881
# differential_evolution step 219: f(x)= 434.6200277824881
# differential_evolution step 220: f(x)= 434.61727459711045
# differential_evolution step 221: f(x)= 434.60089193378843
# differential_evolution step 222: f(x)= 434.60089193378843
# differential_evolution step 223: f(x)= 434.60089193378843
# differential_evolution step 224: f(x)= 434.60089193378843
# differential_evolution step 225: f(x)= 434.58272174319563
# differential_evolution step 226: f(x)= 434.58272174319563
# differential_evolution step 227: f(x)= 434.58272174319563
# differential_evolution step 228: f(x)= 434.58272174319563
# differential_evolution step 229: f(x)= 434.58272174319563
# differential_evolution step 230: f(x)= 434.58272174319563
# differential_evolution step 231: f(x)= 434.58272174319563
# differential_evolution step 232: f(x)= 434.58272174319563
# differential_evolution step 233: f(x)= 434.53043057885856
# differential_evolution step 234: f(x)= 434.53043057885856
# differential_evolution step 235: f(x)= 434.53043057885856
# differential_evolution step 236: f(x)= 434.53043057885856
# differential_evolution step 237: f(x)= 434.53043057885856
# differential_evolution step 238: f(x)= 434.53043057885856
# differential_evolution step 239: f(x)= 434.53043057885856
# differential_evolution step 240: f(x)= 434.53043057885856
# differential_evolution step 241: f(x)= 434.53043057885856
# differential_evolution step 242: f(x)= 434.53043057885856
# differential_evolution step 243: f(x)= 434.53043057885856
# differential_evolution step 244: f(x)= 434.53043057885856
# differential_evolution step 245: f(x)= 434.53043057885856
# differential_evolution step 246: f(x)= 434.53043057885856
# differential_evolution step 247: f(x)= 434.53043057885856
# differential_evolution step 248: f(x)= 434.53043057885856
# differential_evolution step 249: f(x)= 434.53043057885856
# differential_evolution step 250: f(x)= 434.53043057885856
# differential_evolution step 251: f(x)= 434.5256696042152
# differential_evolution step 252: f(x)= 434.5256696042152
# differential_evolution step 253: f(x)= 434.5256696042152
# differential_evolution step 254: f(x)= 434.5256696042152
# differential_evolution step 255: f(x)= 434.5256696042152
# differential_evolution step 256: f(x)= 434.5256696042152
# differential_evolution step 257: f(x)= 434.5256696042152
# differential_evolution step 258: f(x)= 434.5256696042152
# differential_evolution step 259: f(x)= 434.5256696042152
# differential_evolution step 260: f(x)= 434.5256696042152
# differential_evolution step 261: f(x)= 434.52391726960474
# differential_evolution step 262: f(x)= 434.52391726960474
# differential_evolution step 263: f(x)= 434.52391726960474
# differential_evolution step 264: f(x)= 434.52391726960474
# differential_evolution step 265: f(x)= 434.52391726960474
# differential_evolution step 266: f(x)= 434.52391726960474
# differential_evolution step 267: f(x)= 434.5204132202904
# differential_evolution step 268: f(x)= 434.52002541674887
# differential_evolution step 269: f(x)= 434.52002541674887
# differential_evolution step 270: f(x)= 434.52002541674887
# differential_evolution step 271: f(x)= 434.52002541674887
# differential_evolution step 272: f(x)= 434.52002541674887
# differential_evolution step 273: f(x)= 434.52002541674887
# differential_evolution step 274: f(x)= 434.5143145865395
# differential_evolution step 275: f(x)= 434.5143145865395
# differential_evolution step 276: f(x)= 434.5143145865395
# differential_evolution step 277: f(x)= 434.5143145865395
# differential_evolution step 278: f(x)= 434.5143145865395
# differential_evolution step 279: f(x)= 434.5143145865395
# differential_evolution step 280: f(x)= 434.5143145865395
# differential_evolution step 281: f(x)= 434.5137819601209
# differential_evolution step 282: f(x)= 434.5137819601209
# differential_evolution step 283: f(x)= 434.5137819601209
# differential_evolution step 284: f(x)= 434.5137819601209
# differential_evolution step 285: f(x)= 434.5137819601209
# differential_evolution step 286: f(x)= 434.5137819601209
# differential_evolution step 287: f(x)= 434.5137819601209
# differential_evolution step 288: f(x)= 434.5137819601209
# differential_evolution step 289: f(x)= 434.5121189131208
# differential_evolution step 290: f(x)= 434.5121189131208
# differential_evolution step 291: f(x)= 434.5121189131208
# differential_evolution step 292: f(x)= 434.5121189131208
# differential_evolution step 293: f(x)= 434.5121189131208
# differential_evolution step 294: f(x)= 434.5121189131208
# differential_evolution step 295: f(x)= 434.5117550884077
# differential_evolution step 296: f(x)= 434.5117550884077
# differential_evolution step 297: f(x)= 434.5117550884077
# differential_evolution step 298: f(x)= 434.5117550884077
# differential_evolution step 299: f(x)= 434.5107452512061
# differential_evolution step 300: f(x)= 434.5103083668362
# differential_evolution step 301: f(x)= 434.5103083668362
# differential_evolution step 302: f(x)= 434.5103083668362
# differential_evolution step 303: f(x)= 434.5103083668362
# differential_evolution step 304: f(x)= 434.5103083668362
# differential_evolution step 305: f(x)= 434.5103083668362
# differential_evolution step 306: f(x)= 434.5103083668362
# differential_evolution step 307: f(x)= 434.5103083668362
# differential_evolution step 308: f(x)= 434.5103083668362
# differential_evolution step 309: f(x)= 434.5103083668362
# differential_evolution step 310: f(x)= 434.5103083668362
# differential_evolution step 311: f(x)= 434.5103083668362
# differential_evolution step 312: f(x)= 434.5103083668362
# differential_evolution step 313: f(x)= 434.5103083668362
# differential_evolution step 314: f(x)= 434.50895740130784
# differential_evolution step 315: f(x)= 434.50895740130784
# differential_evolution step 316: f(x)= 434.50856038666797
# differential_evolution step 317: f(x)= 434.50856038666797
# differential_evolution step 318: f(x)= 434.50856038666797
# differential_evolution step 319: f(x)= 434.50856038666797
# differential_evolution step 320: f(x)= 434.50856038666797
# differential_evolution step 321: f(x)= 434.50856038666797
# differential_evolution step 322: f(x)= 434.50856038666797
# differential_evolution step 323: f(x)= 434.50856038666797
# differential_evolution step 324: f(x)= 434.50856038666797
# differential_evolution step 325: f(x)= 434.50856038666797
# differential_evolution step 326: f(x)= 434.50856038666797
# differential_evolution step 327: f(x)= 434.50856038666797
# differential_evolution step 328: f(x)= 434.50856038666797
# differential_evolution step 329: f(x)= 434.50856038666797
# differential_evolution step 330: f(x)= 434.50856038666797
# differential_evolution step 331: f(x)= 434.50856038666797
# differential_evolution step 332: f(x)= 434.50856038666797
# differential_evolution step 333: f(x)= 434.50856038666797
# differential_evolution step 334: f(x)= 434.50856038666797
# differential_evolution step 335: f(x)= 434.50856038666797
# differential_evolution step 336: f(x)= 434.50856038666797
# differential_evolution step 337: f(x)= 434.50856038666797
# differential_evolution step 338: f(x)= 434.50856038666797
# differential_evolution step 339: f(x)= 434.50856038666797
# differential_evolution step 340: f(x)= 434.50856038666797
# differential_evolution step 341: f(x)= 434.50856038666797
# differential_evolution step 342: f(x)= 434.50856038666797
# differential_evolution step 343: f(x)= 434.50856038666797
# differential_evolution step 344: f(x)= 434.5082394910988
# differential_evolution step 345: f(x)= 434.5082394910988
# differential_evolution step 346: f(x)= 434.5082394910988
# differential_evolution step 347: f(x)= 434.5082394910988
# differential_evolution step 348: f(x)= 434.5082394910988
# differential_evolution step 349: f(x)= 434.5082394910988
# differential_evolution step 350: f(x)= 434.5081611714611
# differential_evolution step 351: f(x)= 434.5081611714611
# differential_evolution step 352: f(x)= 434.5081611714611
# differential_evolution step 353: f(x)= 434.5081611714611
# differential_evolution step 354: f(x)= 434.5081611714611
# differential_evolution step 355: f(x)= 434.5081611714611
# differential_evolution step 356: f(x)= 434.5081611714611
# differential_evolution step 357: f(x)= 434.5081611714611
# differential_evolution step 358: f(x)= 434.5081611714611
# differential_evolution step 359: f(x)= 434.5081611714611
# differential_evolution step 360: f(x)= 434.5081611714611
# differential_evolution step 361: f(x)= 434.5081296125616
# differential_evolution step 362: f(x)= 434.50810367891035
# differential_evolution step 363: f(x)= 434.50810367891035
# differential_evolution step 364: f(x)= 434.50810367891035
# differential_evolution step 365: f(x)= 434.50810367891035
# differential_evolution step 366: f(x)= 434.50810367891035
# differential_evolution step 367: f(x)= 434.50810367891035
# differential_evolution step 368: f(x)= 434.50800886872014
# differential_evolution step 369: f(x)= 434.5079146487561
# differential_evolution step 370: f(x)= 434.5079146487561
# differential_evolution step 371: f(x)= 434.5079146487561
# differential_evolution step 372: f(x)= 434.5079146487561
# differential_evolution step 373: f(x)= 434.5079008506579
# differential_evolution step 374: f(x)= 434.5079008506579
# differential_evolution step 375: f(x)= 434.5079008506579
# differential_evolution step 376: f(x)= 434.5078564904563
# differential_evolution step 377: f(x)= 434.5078564904563
# differential_evolution step 378: f(x)= 434.5078564904563
# differential_evolution step 379: f(x)= 434.5078564904563
# differential_evolution step 380: f(x)= 434.50779478330054
# differential_evolution step 381: f(x)= 434.50779478330054
# differential_evolution step 382: f(x)= 434.50779478330054
# differential_evolution step 383: f(x)= 434.50779478330054
# differential_evolution step 384: f(x)= 434.50779478330054
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=6.5910, n=1.6299, x_0=39.4235
# Sérsic 2: I_e=2.9693, r_e=6.9906, n=1.1611, x_0=48.9990
# Sérsic 3: I_e=2.3022, r_e=5.8834, n=1.4621, x_0=57.1869
# Chi quadro minimo: 434.507793864046
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(result.x)
# Out:
# [ 9.99999985  6.59095614  1.62986047 39.42346257  2.96926462  6.99062072
#   1.16112242 48.99902102  2.30223736  5.88344716  1.46209426 57.18692407]

# %%
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, radial_profile_error_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2624\1973153750.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2624\1973153750.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=31.5655, r_e=2.8954, n=0.8181, x_0=39.4492
# Sérsic 2: I_e=2.9072, r_e=11.8463, n=1.3071, x_0=48.6707
# Sérsic 3: I_e=3.9572, r_e=3.2413, n=1.0484, x_0=57.2465
# [1.49491463 0.08305113 0.03723411 0.02911928 0.37677062 0.64983928
#  0.09677488 0.12119679 0.94595985 0.57555019 0.18471424 0.09196354]
# 110.68110742777206

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1, x_0_HA[0]+1),   # x_0: circa la posizione di Halpha

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1, x_0_HA[1]+1),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1, x_0_HA[2]+1)
]

# %%
bounds
# Out:
# [(0, 10),
#  (0, 50),
#  (0.1, 10),
#  (38.4492, 40.4492),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (47.6707, 49.6707),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (56.2465, 58.2465)]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 1926.239561860292
# differential_evolution step 2: f(x)= 1926.239561860292
# differential_evolution step 3: f(x)= 896.1527456399095
# differential_evolution step 4: f(x)= 419.73286999811535
# differential_evolution step 5: f(x)= 419.73286999811535
# differential_evolution step 6: f(x)= 405.2064462390861
# differential_evolution step 7: f(x)= 405.2064462390861
# differential_evolution step 8: f(x)= 118.47338209874626
# differential_evolution step 9: f(x)= 118.47338209874626
# differential_evolution step 10: f(x)= 118.47338209874626
# differential_evolution step 11: f(x)= 118.47338209874626
# differential_evolution step 12: f(x)= 118.47338209874626
# differential_evolution step 13: f(x)= 79.64861034453048
# differential_evolution step 14: f(x)= 79.64861034453048
# differential_evolution step 15: f(x)= 79.64861034453048
# differential_evolution step 16: f(x)= 79.64861034453048
# differential_evolution step 17: f(x)= 58.59817161385936
# differential_evolution step 18: f(x)= 58.59817161385936
# differential_evolution step 19: f(x)= 58.59817161385936
# differential_evolution step 20: f(x)= 58.59817161385936
# differential_evolution step 21: f(x)= 58.59817161385936
# differential_evolution step 22: f(x)= 52.39773592076566
# differential_evolution step 23: f(x)= 52.39773592076566
# differential_evolution step 24: f(x)= 52.39773592076566
# differential_evolution step 25: f(x)= 52.39773592076566
# differential_evolution step 26: f(x)= 52.39773592076566
# differential_evolution step 27: f(x)= 51.93557416596143
# differential_evolution step 28: f(x)= 51.93557416596143
# differential_evolution step 29: f(x)= 47.5651152199065
# differential_evolution step 30: f(x)= 47.5651152199065
# differential_evolution step 31: f(x)= 45.575618655695074
# differential_evolution step 32: f(x)= 45.575618655695074
# differential_evolution step 33: f(x)= 43.12625354734102
# differential_evolution step 34: f(x)= 43.12625354734102
# differential_evolution step 35: f(x)= 43.12625354734102
# differential_evolution step 36: f(x)= 37.9208137697595
# differential_evolution step 37: f(x)= 37.9208137697595
# differential_evolution step 38: f(x)= 31.559431800825177
# differential_evolution step 39: f(x)= 31.559431800825177
# differential_evolution step 40: f(x)= 31.559431800825177
# differential_evolution step 41: f(x)= 26.316370139091326
# differential_evolution step 42: f(x)= 26.316370139091326
# differential_evolution step 43: f(x)= 26.316370139091326
# differential_evolution step 44: f(x)= 26.316370139091326
# differential_evolution step 45: f(x)= 26.316370139091326
# differential_evolution step 46: f(x)= 26.316370139091326
# differential_evolution step 47: f(x)= 26.316370139091326
# differential_evolution step 48: f(x)= 26.03848288057461
# differential_evolution step 49: f(x)= 26.03848288057461
# differential_evolution step 50: f(x)= 24.88219315259223
# differential_evolution step 51: f(x)= 24.88219315259223
# differential_evolution step 52: f(x)= 24.88219315259223
# differential_evolution step 53: f(x)= 24.88219315259223
# differential_evolution step 54: f(x)= 24.88219315259223
# differential_evolution step 55: f(x)= 19.188128071070683
# differential_evolution step 56: f(x)= 19.188128071070683
# differential_evolution step 57: f(x)= 19.188128071070683
# differential_evolution step 58: f(x)= 18.84305409092706
# differential_evolution step 59: f(x)= 18.84305409092706
# differential_evolution step 60: f(x)= 18.84305409092706
# differential_evolution step 61: f(x)= 18.84305409092706
# differential_evolution step 62: f(x)= 18.84305409092706
# differential_evolution step 63: f(x)= 18.84305409092706
# differential_evolution step 64: f(x)= 18.072767214823525
# differential_evolution step 65: f(x)= 18.072767214823525
# differential_evolution step 66: f(x)= 18.00251705772536
# differential_evolution step 67: f(x)= 18.00251705772536
# differential_evolution step 68: f(x)= 18.00251705772536
# differential_evolution step 69: f(x)= 18.00251705772536
# differential_evolution step 70: f(x)= 18.00251705772536
# differential_evolution step 71: f(x)= 18.00251705772536
# differential_evolution step 72: f(x)= 17.16697053464268
# differential_evolution step 73: f(x)= 17.16697053464268
# differential_evolution step 74: f(x)= 17.16697053464268
# differential_evolution step 75: f(x)= 17.16697053464268
# differential_evolution step 76: f(x)= 17.16697053464268
# differential_evolution step 77: f(x)= 16.13800138666975
# differential_evolution step 78: f(x)= 16.13800138666975
# differential_evolution step 79: f(x)= 15.875317406800768
# differential_evolution step 80: f(x)= 15.875317406800768
# differential_evolution step 81: f(x)= 15.875317406800768
# differential_evolution step 82: f(x)= 15.855076547812173
# differential_evolution step 83: f(x)= 15.855076547812173
# differential_evolution step 84: f(x)= 15.855076547812173
# differential_evolution step 85: f(x)= 15.855076547812173
# differential_evolution step 86: f(x)= 15.855076547812173
# differential_evolution step 87: f(x)= 15.855076547812173
# differential_evolution step 88: f(x)= 15.855076547812173
# differential_evolution step 89: f(x)= 15.855076547812173
# differential_evolution step 90: f(x)= 15.855076547812173
# differential_evolution step 91: f(x)= 15.855076547812173
# differential_evolution step 92: f(x)= 14.881459995595193
# differential_evolution step 93: f(x)= 14.881459995595193
# differential_evolution step 94: f(x)= 14.881459995595193
# differential_evolution step 95: f(x)= 14.842971906217162
# differential_evolution step 96: f(x)= 14.31733738626703
# differential_evolution step 97: f(x)= 14.31733738626703
# differential_evolution step 98: f(x)= 13.68862807119778
# differential_evolution step 99: f(x)= 13.68862807119778
# differential_evolution step 100: f(x)= 13.68862807119778
# differential_evolution step 101: f(x)= 13.68862807119778
# differential_evolution step 102: f(x)= 13.68862807119778
# differential_evolution step 103: f(x)= 13.68862807119778
# differential_evolution step 104: f(x)= 13.68862807119778
# differential_evolution step 105: f(x)= 13.68862807119778
# differential_evolution step 106: f(x)= 13.68862807119778
# differential_evolution step 107: f(x)= 13.68862807119778
# differential_evolution step 108: f(x)= 13.68862807119778
# differential_evolution step 109: f(x)= 13.68862807119778
# differential_evolution step 110: f(x)= 13.68862807119778
# differential_evolution step 111: f(x)= 13.68862807119778
# differential_evolution step 112: f(x)= 13.272008941764904
# differential_evolution step 113: f(x)= 13.272008941764904
# differential_evolution step 114: f(x)= 13.272008941764904
# differential_evolution step 115: f(x)= 12.50405839871574
# differential_evolution step 116: f(x)= 12.50405839871574
# differential_evolution step 117: f(x)= 12.50405839871574
# differential_evolution step 118: f(x)= 12.50405839871574
# differential_evolution step 119: f(x)= 12.50405839871574
# differential_evolution step 120: f(x)= 12.50405839871574
# differential_evolution step 121: f(x)= 12.50405839871574
# differential_evolution step 122: f(x)= 12.50405839871574
# differential_evolution step 123: f(x)= 11.847430776942506
# differential_evolution step 124: f(x)= 11.847430776942506
# differential_evolution step 125: f(x)= 11.847430776942506
# differential_evolution step 126: f(x)= 11.847430776942506
# differential_evolution step 127: f(x)= 11.847430776942506
# differential_evolution step 128: f(x)= 11.847430776942506
# differential_evolution step 129: f(x)= 11.847430776942506
# differential_evolution step 130: f(x)= 11.847430776942506
# differential_evolution step 131: f(x)= 11.847430776942506
# differential_evolution step 132: f(x)= 11.847430776942506
# differential_evolution step 133: f(x)= 11.847430776942506
# differential_evolution step 134: f(x)= 11.847430776942506
# differential_evolution step 135: f(x)= 11.847430776942506
# differential_evolution step 136: f(x)= 11.847430776942506
# differential_evolution step 137: f(x)= 11.847430776942506
# differential_evolution step 138: f(x)= 11.847430776942506
# differential_evolution step 139: f(x)= 11.847430776942506
# differential_evolution step 140: f(x)= 11.847430776942506
# differential_evolution step 141: f(x)= 11.847430776942506
# differential_evolution step 142: f(x)= 11.847430776942506
# differential_evolution step 143: f(x)= 11.847430776942506
# differential_evolution step 144: f(x)= 11.847430776942506
# differential_evolution step 145: f(x)= 11.847430776942506
# differential_evolution step 146: f(x)= 11.284178475507682
# differential_evolution step 147: f(x)= 11.284178475507682
# differential_evolution step 148: f(x)= 11.284178475507682
# differential_evolution step 149: f(x)= 11.284178475507682
# differential_evolution step 150: f(x)= 11.284178475507682
# differential_evolution step 151: f(x)= 11.284178475507682
# differential_evolution step 152: f(x)= 11.284178475507682
# differential_evolution step 153: f(x)= 11.284178475507682
# differential_evolution step 154: f(x)= 11.284178475507682
# differential_evolution step 155: f(x)= 11.284178475507682
# differential_evolution step 156: f(x)= 11.284178475507682
# differential_evolution step 157: f(x)= 11.284178475507682
# differential_evolution step 158: f(x)= 11.284178475507682
# differential_evolution step 159: f(x)= 11.284178475507682
# differential_evolution step 160: f(x)= 11.284178475507682
# differential_evolution step 161: f(x)= 11.284178475507682
# differential_evolution step 162: f(x)= 11.284178475507682
# differential_evolution step 163: f(x)= 11.284178475507682
# differential_evolution step 164: f(x)= 11.284178475507682
# differential_evolution step 165: f(x)= 11.284178475507682
# differential_evolution step 166: f(x)= 11.284178475507682
# differential_evolution step 167: f(x)= 11.284178475507682
# differential_evolution step 168: f(x)= 11.284178475507682
# differential_evolution step 169: f(x)= 11.284178475507682
# differential_evolution step 170: f(x)= 11.284178475507682
# differential_evolution step 171: f(x)= 11.284178475507682
# differential_evolution step 172: f(x)= 11.284178475507682
# differential_evolution step 173: f(x)= 11.284178475507682
# differential_evolution step 174: f(x)= 11.284178475507682
# differential_evolution step 175: f(x)= 11.284178475507682
# differential_evolution step 176: f(x)= 11.284178475507682
# differential_evolution step 177: f(x)= 11.284178475507682
# differential_evolution step 178: f(x)= 11.284178475507682
# differential_evolution step 179: f(x)= 11.284178475507682
# differential_evolution step 180: f(x)= 11.284178475507682
# differential_evolution step 181: f(x)= 11.284178475507682
# differential_evolution step 182: f(x)= 11.284178475507682
# differential_evolution step 183: f(x)= 11.284178475507682
# differential_evolution step 184: f(x)= 11.284178475507682
# differential_evolution step 185: f(x)= 11.284178475507682
# differential_evolution step 186: f(x)= 11.284178475507682
# differential_evolution step 187: f(x)= 11.284178475507682
# differential_evolution step 188: f(x)= 11.284178475507682
# differential_evolution step 189: f(x)= 11.284178475507682
# differential_evolution step 190: f(x)= 11.284178475507682
# differential_evolution step 191: f(x)= 11.284178475507682
# differential_evolution step 192: f(x)= 11.284178475507682
# differential_evolution step 193: f(x)= 11.284178475507682
# differential_evolution step 194: f(x)= 11.284178475507682
# differential_evolution step 195: f(x)= 11.184965752958338
# differential_evolution step 196: f(x)= 11.091344502666656
# differential_evolution step 197: f(x)= 11.091344502666656
# differential_evolution step 198: f(x)= 11.091344502666656
# differential_evolution step 199: f(x)= 11.091344502666656
# differential_evolution step 200: f(x)= 11.091344502666656
# differential_evolution step 201: f(x)= 11.091344502666656
# differential_evolution step 202: f(x)= 11.06522286949663
# differential_evolution step 203: f(x)= 11.06522286949663
# differential_evolution step 204: f(x)= 11.06522286949663
# differential_evolution step 205: f(x)= 11.06522286949663
# differential_evolution step 206: f(x)= 11.06522286949663
# differential_evolution step 207: f(x)= 11.06522286949663
# differential_evolution step 208: f(x)= 11.06522286949663
# differential_evolution step 209: f(x)= 11.06522286949663
# differential_evolution step 210: f(x)= 11.06522286949663
# differential_evolution step 211: f(x)= 11.034387914567693
# differential_evolution step 212: f(x)= 11.034387914567693
# differential_evolution step 213: f(x)= 11.034387914567693
# differential_evolution step 214: f(x)= 11.034387914567693
# differential_evolution step 215: f(x)= 10.976637793168928
# differential_evolution step 216: f(x)= 10.976637793168928
# differential_evolution step 217: f(x)= 10.96570324359734
# differential_evolution step 218: f(x)= 10.96570324359734
# differential_evolution step 219: f(x)= 10.96570324359734
# differential_evolution step 220: f(x)= 10.96570324359734
# differential_evolution step 221: f(x)= 10.96570324359734
# differential_evolution step 222: f(x)= 10.96570324359734
# differential_evolution step 223: f(x)= 10.96570324359734
# differential_evolution step 224: f(x)= 10.96570324359734
# differential_evolution step 225: f(x)= 10.96570324359734
# differential_evolution step 226: f(x)= 10.91172106104876
# differential_evolution step 227: f(x)= 10.91172106104876
# differential_evolution step 228: f(x)= 10.91172106104876
# differential_evolution step 229: f(x)= 10.91172106104876
# differential_evolution step 230: f(x)= 10.91172106104876
# differential_evolution step 231: f(x)= 10.91172106104876
# differential_evolution step 232: f(x)= 10.91172106104876
# differential_evolution step 233: f(x)= 10.91172106104876
# differential_evolution step 234: f(x)= 10.91172106104876
# differential_evolution step 235: f(x)= 10.91172106104876
# differential_evolution step 236: f(x)= 10.91172106104876
# differential_evolution step 237: f(x)= 10.91172106104876
# differential_evolution step 238: f(x)= 10.91172106104876
# differential_evolution step 239: f(x)= 10.91172106104876
# differential_evolution step 240: f(x)= 10.91172106104876
# differential_evolution step 241: f(x)= 10.91172106104876
# differential_evolution step 242: f(x)= 10.91172106104876
# differential_evolution step 243: f(x)= 10.91172106104876
# differential_evolution step 244: f(x)= 10.91172106104876
# differential_evolution step 245: f(x)= 10.91172106104876
# differential_evolution step 246: f(x)= 10.91172106104876
# differential_evolution step 247: f(x)= 10.91172106104876
# differential_evolution step 248: f(x)= 10.91172106104876
# differential_evolution step 249: f(x)= 10.91172106104876
# differential_evolution step 250: f(x)= 10.91172106104876
# differential_evolution step 251: f(x)= 10.91172106104876
# differential_evolution step 252: f(x)= 10.91172106104876
# differential_evolution step 253: f(x)= 10.91172106104876
# differential_evolution step 254: f(x)= 10.898138329803563
# differential_evolution step 255: f(x)= 10.898138329803563
# differential_evolution step 256: f(x)= 10.898138329803563
# differential_evolution step 257: f(x)= 10.879260967106598
# differential_evolution step 258: f(x)= 10.879260967106598
# differential_evolution step 259: f(x)= 10.879260967106598
# differential_evolution step 260: f(x)= 10.879260967106598
# differential_evolution step 261: f(x)= 10.879260967106598
# differential_evolution step 262: f(x)= 10.879260967106598
# differential_evolution step 263: f(x)= 10.879260967106598
# differential_evolution step 264: f(x)= 10.879260967106598
# differential_evolution step 265: f(x)= 10.879260967106598
# differential_evolution step 266: f(x)= 10.875834957457888
# differential_evolution step 267: f(x)= 10.875834957457888
# differential_evolution step 268: f(x)= 10.875834957457888
# differential_evolution step 269: f(x)= 10.856787107259477
# differential_evolution step 270: f(x)= 10.844818991884482
# differential_evolution step 271: f(x)= 10.8095687448181
# differential_evolution step 272: f(x)= 10.8095687448181
# differential_evolution step 273: f(x)= 10.8095687448181
# differential_evolution step 274: f(x)= 10.8095687448181
# differential_evolution step 275: f(x)= 10.8095687448181
# differential_evolution step 276: f(x)= 10.8095687448181
# differential_evolution step 277: f(x)= 10.8095687448181
# differential_evolution step 278: f(x)= 10.8095687448181
# differential_evolution step 279: f(x)= 10.78966634526461
# differential_evolution step 280: f(x)= 10.78966634526461
# differential_evolution step 281: f(x)= 10.78966634526461
# differential_evolution step 282: f(x)= 10.78966634526461
# differential_evolution step 283: f(x)= 10.78966634526461
# differential_evolution step 284: f(x)= 10.78966634526461
# differential_evolution step 285: f(x)= 10.78966634526461
# differential_evolution step 286: f(x)= 10.78966634526461
# differential_evolution step 287: f(x)= 10.78966634526461
# differential_evolution step 288: f(x)= 10.78966634526461
# differential_evolution step 289: f(x)= 10.78966634526461
# differential_evolution step 290: f(x)= 10.78966634526461
# differential_evolution step 291: f(x)= 10.78966634526461
# differential_evolution step 292: f(x)= 10.78966634526461
# differential_evolution step 293: f(x)= 10.78966634526461
# differential_evolution step 294: f(x)= 10.78966634526461
# differential_evolution step 295: f(x)= 10.78966634526461
# differential_evolution step 296: f(x)= 10.78966634526461
# differential_evolution step 297: f(x)= 10.78966634526461
# differential_evolution step 298: f(x)= 10.78966634526461
# differential_evolution step 299: f(x)= 10.78966634526461
# differential_evolution step 300: f(x)= 10.78966634526461
# differential_evolution step 301: f(x)= 10.78966634526461
# differential_evolution step 302: f(x)= 10.78966634526461
# differential_evolution step 303: f(x)= 10.78966634526461
# differential_evolution step 304: f(x)= 10.78966634526461
# differential_evolution step 305: f(x)= 10.78966634526461
# differential_evolution step 306: f(x)= 10.78966634526461
# differential_evolution step 307: f(x)= 10.78966634526461
# differential_evolution step 308: f(x)= 10.78966634526461
# differential_evolution step 309: f(x)= 10.78966634526461
# differential_evolution step 310: f(x)= 10.78966634526461
# differential_evolution step 311: f(x)= 10.78966634526461
# differential_evolution step 312: f(x)= 10.78966634526461
# differential_evolution step 313: f(x)= 10.78966634526461
# differential_evolution step 314: f(x)= 10.78966634526461
# differential_evolution step 315: f(x)= 10.78966634526461
# differential_evolution step 316: f(x)= 10.78966634526461
# differential_evolution step 317: f(x)= 10.78966634526461
# differential_evolution step 318: f(x)= 10.78966634526461
# differential_evolution step 319: f(x)= 10.78966634526461
# differential_evolution step 320: f(x)= 10.78966634526461
# differential_evolution step 321: f(x)= 10.78966634526461
# differential_evolution step 322: f(x)= 10.78966634526461
# differential_evolution step 323: f(x)= 10.758944822690244
# differential_evolution step 324: f(x)= 10.758944822690244
# differential_evolution step 325: f(x)= 10.758944822690244
# differential_evolution step 326: f(x)= 10.758944822690244
# differential_evolution step 327: f(x)= 10.758944822690244
# differential_evolution step 328: f(x)= 10.758944822690244
# differential_evolution step 329: f(x)= 10.758944822690244
# differential_evolution step 330: f(x)= 10.758944822690244
# differential_evolution step 331: f(x)= 10.758944822690244
# differential_evolution step 332: f(x)= 10.758944822690244
# differential_evolution step 333: f(x)= 10.758944822690244
# differential_evolution step 334: f(x)= 10.758944822690244
# differential_evolution step 335: f(x)= 10.758944822690244
# differential_evolution step 336: f(x)= 10.758944822690244
# differential_evolution step 337: f(x)= 10.758944822690244
# differential_evolution step 338: f(x)= 10.758944822690244
# differential_evolution step 339: f(x)= 10.758944822690244
# differential_evolution step 340: f(x)= 10.754027792639597
# differential_evolution step 341: f(x)= 10.743071097682297
# differential_evolution step 342: f(x)= 10.743071097682297
# differential_evolution step 343: f(x)= 10.743071097682297
# differential_evolution step 344: f(x)= 10.743071097682297
# differential_evolution step 345: f(x)= 10.743071097682297
# differential_evolution step 346: f(x)= 10.743071097682297
# differential_evolution step 347: f(x)= 10.743071097682297
# differential_evolution step 348: f(x)= 10.743071097682297
# differential_evolution step 349: f(x)= 10.743071097682297
# differential_evolution step 350: f(x)= 10.743071097682297
# differential_evolution step 351: f(x)= 10.743071097682297
# differential_evolution step 352: f(x)= 10.743071097682297
# differential_evolution step 353: f(x)= 10.743071097682297
# differential_evolution step 354: f(x)= 10.743071097682297
# differential_evolution step 355: f(x)= 10.743071097682297
# differential_evolution step 356: f(x)= 10.743071097682297
# differential_evolution step 357: f(x)= 10.737018007656394
# differential_evolution step 358: f(x)= 10.732095649811642
# differential_evolution step 359: f(x)= 10.732095649811642
# differential_evolution step 360: f(x)= 10.732095649811642
# differential_evolution step 361: f(x)= 10.732095649811642
# differential_evolution step 362: f(x)= 10.732095649811642
# differential_evolution step 363: f(x)= 10.732095649811642
# differential_evolution step 364: f(x)= 10.732095649811642
# differential_evolution step 365: f(x)= 10.732095649811642
# differential_evolution step 366: f(x)= 10.732095649811642
# differential_evolution step 367: f(x)= 10.732095649811642
# differential_evolution step 368: f(x)= 10.732095649811642
# differential_evolution step 369: f(x)= 10.732095649811642
# differential_evolution step 370: f(x)= 10.730646817329916
# differential_evolution step 371: f(x)= 10.730646817329916
# differential_evolution step 372: f(x)= 10.730646817329916
# differential_evolution step 373: f(x)= 10.730560376815664
# differential_evolution step 374: f(x)= 10.730560376815664
# differential_evolution step 375: f(x)= 10.730560376815664
# differential_evolution step 376: f(x)= 10.726121855306685
# differential_evolution step 377: f(x)= 10.726121855306685
# differential_evolution step 378: f(x)= 10.726121855306685
# differential_evolution step 379: f(x)= 10.726121855306685
# differential_evolution step 380: f(x)= 10.726121855306685
# differential_evolution step 381: f(x)= 10.726121855306685
# differential_evolution step 382: f(x)= 10.719637342525788
# differential_evolution step 383: f(x)= 10.719637342525788
# differential_evolution step 384: f(x)= 10.719637342525788
# differential_evolution step 385: f(x)= 10.719637342525788
# differential_evolution step 386: f(x)= 10.719637342525788
# differential_evolution step 387: f(x)= 10.713047181468193
# differential_evolution step 388: f(x)= 10.713047181468193
# differential_evolution step 389: f(x)= 10.713047181468193
# differential_evolution step 390: f(x)= 10.713047181468193
# differential_evolution step 391: f(x)= 10.710040987404376
# differential_evolution step 392: f(x)= 10.710040987404376
# differential_evolution step 393: f(x)= 10.710040987404376
# differential_evolution step 394: f(x)= 10.710040987404376
# differential_evolution step 395: f(x)= 10.710040987404376
# differential_evolution step 396: f(x)= 10.710040987404376
# differential_evolution step 397: f(x)= 10.710040987404376
# differential_evolution step 398: f(x)= 10.710040987404376
# differential_evolution step 399: f(x)= 10.705914877226544
# differential_evolution step 400: f(x)= 10.705914877226544
# differential_evolution step 401: f(x)= 10.693214669236761
# differential_evolution step 402: f(x)= 10.693214669236761
# differential_evolution step 403: f(x)= 10.693214669236761
# differential_evolution step 404: f(x)= 10.693214669236761
# differential_evolution step 405: f(x)= 10.693214669236761
# differential_evolution step 406: f(x)= 10.693214669236761
# differential_evolution step 407: f(x)= 10.693214669236761
# differential_evolution step 408: f(x)= 10.693214669236761
# differential_evolution step 409: f(x)= 10.693214669236761
# differential_evolution step 410: f(x)= 10.693214669236761
# differential_evolution step 411: f(x)= 10.693214669236761
# differential_evolution step 412: f(x)= 10.693214669236761
# differential_evolution step 413: f(x)= 10.693214669236761
# differential_evolution step 414: f(x)= 10.693214669236761
# differential_evolution step 415: f(x)= 10.693214669236761
# differential_evolution step 416: f(x)= 10.693214669236761
# differential_evolution step 417: f(x)= 10.693214669236761
# differential_evolution step 418: f(x)= 10.693214669236761
# differential_evolution step 419: f(x)= 10.693214669236761
# differential_evolution step 420: f(x)= 10.693214669236761
# differential_evolution step 421: f(x)= 10.689449111408123
# differential_evolution step 422: f(x)= 10.689449111408123
# differential_evolution step 423: f(x)= 10.689449111408123
# differential_evolution step 424: f(x)= 10.689449111408123
# differential_evolution step 425: f(x)= 10.689449111408123
# differential_evolution step 426: f(x)= 10.689449111408123
# differential_evolution step 427: f(x)= 10.689449111408123
# differential_evolution step 428: f(x)= 10.689449111408123
# differential_evolution step 429: f(x)= 10.689449111408123
# differential_evolution step 430: f(x)= 10.689449111408123
# differential_evolution step 431: f(x)= 10.687121829307241
# differential_evolution step 432: f(x)= 10.687121829307241
# differential_evolution step 433: f(x)= 10.687121829307241
# differential_evolution step 434: f(x)= 10.685178496112975
# differential_evolution step 435: f(x)= 10.685178496112975
# differential_evolution step 436: f(x)= 10.685178496112975
# differential_evolution step 437: f(x)= 10.685178496112975
# differential_evolution step 438: f(x)= 10.685178496112975
# differential_evolution step 439: f(x)= 10.685178496112975
# differential_evolution step 440: f(x)= 10.685178496112975
# differential_evolution step 441: f(x)= 10.685178496112975
# differential_evolution step 442: f(x)= 10.685178496112975
# differential_evolution step 443: f(x)= 10.685178496112975
# differential_evolution step 444: f(x)= 10.685178496112975
# differential_evolution step 445: f(x)= 10.685178496112975
# differential_evolution step 446: f(x)= 10.685178496112975
# differential_evolution step 447: f(x)= 10.685178496112975
# differential_evolution step 448: f(x)= 10.685178496112975
# differential_evolution step 449: f(x)= 10.685178496112975
# differential_evolution step 450: f(x)= 10.685178496112975
# differential_evolution step 451: f(x)= 10.685178496112975
# differential_evolution step 452: f(x)= 10.680828074472542
# differential_evolution step 453: f(x)= 10.680828074472542
# differential_evolution step 454: f(x)= 10.680828074472542
# differential_evolution step 455: f(x)= 10.680828074472542
# differential_evolution step 456: f(x)= 10.680828074472542
# differential_evolution step 457: f(x)= 10.680828074472542
# differential_evolution step 458: f(x)= 10.678671582735017
# differential_evolution step 459: f(x)= 10.678671582735017
# differential_evolution step 460: f(x)= 10.678671582735017
# differential_evolution step 461: f(x)= 10.678671582735017
# differential_evolution step 462: f(x)= 10.678671582735017
# differential_evolution step 463: f(x)= 10.678671582735017
# differential_evolution step 464: f(x)= 10.678671582735017
# differential_evolution step 465: f(x)= 10.678671582735017
# differential_evolution step 466: f(x)= 10.678671582735017
# differential_evolution step 467: f(x)= 10.678671582735017
# differential_evolution step 468: f(x)= 10.678671582735017
# differential_evolution step 469: f(x)= 10.678671582735017
# differential_evolution step 470: f(x)= 10.678671582735017
# differential_evolution step 471: f(x)= 10.678671582735017
# differential_evolution step 472: f(x)= 10.678572579735617
# differential_evolution step 473: f(x)= 10.678572579735617
# differential_evolution step 474: f(x)= 10.678572579735617
# differential_evolution step 475: f(x)= 10.678572579735617
# differential_evolution step 476: f(x)= 10.678572579735617
# differential_evolution step 477: f(x)= 10.678572579735617
# differential_evolution step 478: f(x)= 10.678572579735617
# differential_evolution step 479: f(x)= 10.678572579735617
# differential_evolution step 480: f(x)= 10.678572579735617
# differential_evolution step 481: f(x)= 10.678221554532104
# differential_evolution step 482: f(x)= 10.676121013096726
# differential_evolution step 483: f(x)= 10.676121013096726
# differential_evolution step 484: f(x)= 10.676121013096726
# differential_evolution step 485: f(x)= 10.676121013096726
# differential_evolution step 486: f(x)= 10.676121013096726
# differential_evolution step 487: f(x)= 10.676121013096726
# differential_evolution step 488: f(x)= 10.676121013096726
# differential_evolution step 489: f(x)= 10.675342876591351
# differential_evolution step 490: f(x)= 10.675342876591351
# differential_evolution step 491: f(x)= 10.675342876591351
# differential_evolution step 492: f(x)= 10.675342876591351
# differential_evolution step 493: f(x)= 10.675342876591351
# differential_evolution step 494: f(x)= 10.675342876591351
# differential_evolution step 495: f(x)= 10.675342876591351
# differential_evolution step 496: f(x)= 10.675342876591351
# differential_evolution step 497: f(x)= 10.675342876591351
# differential_evolution step 498: f(x)= 10.675342876591351
# differential_evolution step 499: f(x)= 10.675342876591351
# differential_evolution step 500: f(x)= 10.675342876591351
# differential_evolution step 501: f(x)= 10.675342876591351
# differential_evolution step 502: f(x)= 10.675342876591351
# differential_evolution step 503: f(x)= 10.675342876591351
# differential_evolution step 504: f(x)= 10.675342876591351
# differential_evolution step 505: f(x)= 10.675342876591351
# differential_evolution step 506: f(x)= 10.675342876591351
# differential_evolution step 507: f(x)= 10.675342876591351
# differential_evolution step 508: f(x)= 10.675342876591351
# differential_evolution step 509: f(x)= 10.675342876591351
# differential_evolution step 510: f(x)= 10.675342876591351
# differential_evolution step 511: f(x)= 10.675342876591351
# differential_evolution step 512: f(x)= 10.675342876591351
# differential_evolution step 513: f(x)= 10.675342876591351
# differential_evolution step 514: f(x)= 10.675342876591351
# differential_evolution step 515: f(x)= 10.675342876591351
# differential_evolution step 516: f(x)= 10.675342876591351
# differential_evolution step 517: f(x)= 10.675182822891774
# differential_evolution step 518: f(x)= 10.675182822891774
# differential_evolution step 519: f(x)= 10.675182822891774
# differential_evolution step 520: f(x)= 10.675182822891774
# differential_evolution step 521: f(x)= 10.675182822891774
# differential_evolution step 522: f(x)= 10.675182822891774
# differential_evolution step 523: f(x)= 10.675182822891774
# differential_evolution step 524: f(x)= 10.675182822891774
# differential_evolution step 525: f(x)= 10.675182822891774
# differential_evolution step 526: f(x)= 10.675182822891774
# differential_evolution step 527: f(x)= 10.675182822891774
# differential_evolution step 528: f(x)= 10.675182822891774
# differential_evolution step 529: f(x)= 10.675182822891774
# differential_evolution step 530: f(x)= 10.675182822891774
# differential_evolution step 531: f(x)= 10.675182822891774
# differential_evolution step 532: f(x)= 10.675182822891774
# differential_evolution step 533: f(x)= 10.675182822891774
# differential_evolution step 534: f(x)= 10.675182822891774
# differential_evolution step 535: f(x)= 10.675182822891774
# differential_evolution step 536: f(x)= 10.675182822891774
# differential_evolution step 537: f(x)= 10.675182822891774
# differential_evolution step 538: f(x)= 10.675182822891774
# differential_evolution step 539: f(x)= 10.675066933143368
# differential_evolution step 540: f(x)= 10.673015156952872
# differential_evolution step 541: f(x)= 10.673015156952872
# differential_evolution step 542: f(x)= 10.673015156952872
# differential_evolution step 543: f(x)= 10.673015156952872
# differential_evolution step 544: f(x)= 10.673015156952872
# differential_evolution step 545: f(x)= 10.673015156952872
# differential_evolution step 546: f(x)= 10.673015156952872
# differential_evolution step 547: f(x)= 10.673015156952872
# differential_evolution step 548: f(x)= 10.673015156952872
# differential_evolution step 549: f(x)= 10.673015156952872
# differential_evolution step 550: f(x)= 10.673015156952872
# differential_evolution step 551: f(x)= 10.673015156952872
# differential_evolution step 552: f(x)= 10.673015156952872
# differential_evolution step 553: f(x)= 10.673015156952872
# differential_evolution step 554: f(x)= 10.673015156952872
# differential_evolution step 555: f(x)= 10.673015156952872
# differential_evolution step 556: f(x)= 10.673015156952872
# differential_evolution step 557: f(x)= 10.673015156952872
# differential_evolution step 558: f(x)= 10.673015156952872
# differential_evolution step 559: f(x)= 10.673015156952872
# differential_evolution step 560: f(x)= 10.673015156952872
# differential_evolution step 561: f(x)= 10.673015156952872
# differential_evolution step 562: f(x)= 10.673015156952872
# differential_evolution step 563: f(x)= 10.673015156952872
# differential_evolution step 564: f(x)= 10.673015156952872
# differential_evolution step 565: f(x)= 10.673015156952872
# differential_evolution step 566: f(x)= 10.673015156952872
# differential_evolution step 567: f(x)= 10.673015156952872
# differential_evolution step 568: f(x)= 10.673015156952872
# differential_evolution step 569: f(x)= 10.673015156952872
# differential_evolution step 570: f(x)= 10.673015156952872
# differential_evolution step 571: f(x)= 10.673015156952872
# differential_evolution step 572: f(x)= 10.673015156952872
# differential_evolution step 573: f(x)= 10.673015156952872
# differential_evolution step 574: f(x)= 10.673015156952872
# differential_evolution step 575: f(x)= 10.673015156952872
# differential_evolution step 576: f(x)= 10.673015156952872
# differential_evolution step 577: f(x)= 10.673015156952872
# differential_evolution step 578: f(x)= 10.673015156952872
# differential_evolution step 579: f(x)= 10.673015156952872
# differential_evolution step 580: f(x)= 10.673015156952872
# differential_evolution step 581: f(x)= 10.672772618007164
# differential_evolution step 582: f(x)= 10.672772618007164
# differential_evolution step 583: f(x)= 10.672772618007164
# differential_evolution step 584: f(x)= 10.672772618007164
# differential_evolution step 585: f(x)= 10.672772618007164
# differential_evolution step 586: f(x)= 10.672772618007164
# differential_evolution step 587: f(x)= 10.672772618007164
# differential_evolution step 588: f(x)= 10.672772618007164
# differential_evolution step 589: f(x)= 10.672772618007164
# differential_evolution step 590: f(x)= 10.672772618007164
# differential_evolution step 591: f(x)= 10.672769515035744
# differential_evolution step 592: f(x)= 10.672769515035744
# differential_evolution step 593: f(x)= 10.672769515035744
# differential_evolution step 594: f(x)= 10.672769515035744
# differential_evolution step 595: f(x)= 10.672769515035744
# differential_evolution step 596: f(x)= 10.672769515035744
# differential_evolution step 597: f(x)= 10.672769515035744
# differential_evolution step 598: f(x)= 10.672769515035744
# differential_evolution step 599: f(x)= 10.672424333247422
# differential_evolution step 600: f(x)= 10.672424333247422
# differential_evolution step 601: f(x)= 10.672424333247422
# differential_evolution step 602: f(x)= 10.672424333247422
# differential_evolution step 603: f(x)= 10.672424333247422
# differential_evolution step 604: f(x)= 10.672424333247422
# differential_evolution step 605: f(x)= 10.672424333247422
# differential_evolution step 606: f(x)= 10.672424333247422
# differential_evolution step 607: f(x)= 10.672424333247422
# differential_evolution step 608: f(x)= 10.672424333247422
# differential_evolution step 609: f(x)= 10.672424333247422
# differential_evolution step 610: f(x)= 10.672424333247422
# differential_evolution step 611: f(x)= 10.672424333247422
# differential_evolution step 612: f(x)= 10.672424333247422
# differential_evolution step 613: f(x)= 10.672424333247422
# differential_evolution step 614: f(x)= 10.672424333247422
# differential_evolution step 615: f(x)= 10.672424333247422
# differential_evolution step 616: f(x)= 10.672424333247422
# differential_evolution step 617: f(x)= 10.672424333247422
# differential_evolution step 618: f(x)= 10.672424333247422
# differential_evolution step 619: f(x)= 10.672424333247422
# differential_evolution step 620: f(x)= 10.672424333247422
# differential_evolution step 621: f(x)= 10.672424333247422
# differential_evolution step 622: f(x)= 10.672424333247422
# differential_evolution step 623: f(x)= 10.672424333247422
# differential_evolution step 624: f(x)= 10.672394144388312
# differential_evolution step 625: f(x)= 10.672394144388312
# differential_evolution step 626: f(x)= 10.672394144388312
# differential_evolution step 627: f(x)= 10.672394144388312
# differential_evolution step 628: f(x)= 10.672394144388312
# differential_evolution step 629: f(x)= 10.672394144388312
# differential_evolution step 630: f(x)= 10.672394144388312
# differential_evolution step 631: f(x)= 10.672394144388312
# differential_evolution step 632: f(x)= 10.672394144388312
# differential_evolution step 633: f(x)= 10.672394144388312
# differential_evolution step 634: f(x)= 10.672394144388312
# differential_evolution step 635: f(x)= 10.672394144388312
# differential_evolution step 636: f(x)= 10.672394144388312
# differential_evolution step 637: f(x)= 10.672394144388312
# differential_evolution step 638: f(x)= 10.672394144388312
# differential_evolution step 639: f(x)= 10.672394144388312
# differential_evolution step 640: f(x)= 10.672394144388312
# differential_evolution step 641: f(x)= 10.672289888256834
# differential_evolution step 642: f(x)= 10.672289888256834
# differential_evolution step 643: f(x)= 10.672289888256834
# differential_evolution step 644: f(x)= 10.672289888256834
# differential_evolution step 645: f(x)= 10.672289888256834
# differential_evolution step 646: f(x)= 10.672224892450823
# differential_evolution step 647: f(x)= 10.672224892450823
# differential_evolution step 648: f(x)= 10.672224892450823
# differential_evolution step 649: f(x)= 10.672224892450823
# differential_evolution step 650: f(x)= 10.672224892450823
# differential_evolution step 651: f(x)= 10.672224892450823
# differential_evolution step 652: f(x)= 10.672224892450823
# differential_evolution step 653: f(x)= 10.672167546259702
# differential_evolution step 654: f(x)= 10.672167546259702
# differential_evolution step 655: f(x)= 10.672167546259702
# differential_evolution step 656: f(x)= 10.672167546259702
# differential_evolution step 657: f(x)= 10.672167546259702
# differential_evolution step 658: f(x)= 10.672167546259702
# differential_evolution step 659: f(x)= 10.672167546259702
# differential_evolution step 660: f(x)= 10.672167546259702
# differential_evolution step 661: f(x)= 10.672167546259702
# differential_evolution step 662: f(x)= 10.672167546259702
# differential_evolution step 663: f(x)= 10.672167546259702
# differential_evolution step 664: f(x)= 10.672167546259702
# differential_evolution step 665: f(x)= 10.672167546259702
# differential_evolution step 666: f(x)= 10.672167546259702
# differential_evolution step 667: f(x)= 10.672162475226106
# differential_evolution step 668: f(x)= 10.672091813956467
# differential_evolution step 669: f(x)= 10.672085394519842
# differential_evolution step 670: f(x)= 10.672085394519842
# differential_evolution step 671: f(x)= 10.672085394519842
# differential_evolution step 672: f(x)= 10.672085394519842
# differential_evolution step 673: f(x)= 10.672085394519842
# differential_evolution step 674: f(x)= 10.672085394519842
# differential_evolution step 675: f(x)= 10.672085394519842
# differential_evolution step 676: f(x)= 10.672058336560822
# differential_evolution step 677: f(x)= 10.672058336560822
# differential_evolution step 678: f(x)= 10.67204495881351
# differential_evolution step 679: f(x)= 10.67204495881351
# differential_evolution step 680: f(x)= 10.67204495881351
# differential_evolution step 681: f(x)= 10.67204495881351
# differential_evolution step 682: f(x)= 10.67204495881351
# differential_evolution step 683: f(x)= 10.67204495881351
# differential_evolution step 684: f(x)= 10.67204495881351
# differential_evolution step 685: f(x)= 10.67204495881351
# differential_evolution step 686: f(x)= 10.67204495881351
# differential_evolution step 687: f(x)= 10.672010548066925
# differential_evolution step 688: f(x)= 10.672010548066925
# differential_evolution step 689: f(x)= 10.672010548066925
# differential_evolution step 690: f(x)= 10.672010548066925
# differential_evolution step 691: f(x)= 10.672010548066925
# differential_evolution step 692: f(x)= 10.672010548066925
# differential_evolution step 693: f(x)= 10.672010548066925
# differential_evolution step 694: f(x)= 10.672010548066925
# differential_evolution step 695: f(x)= 10.672006766955699
# differential_evolution step 696: f(x)= 10.672006766955699
# differential_evolution step 697: f(x)= 10.672006766955699
# differential_evolution step 698: f(x)= 10.672006766955699
# differential_evolution step 699: f(x)= 10.671947807557636
# differential_evolution step 700: f(x)= 10.671947807557636
# differential_evolution step 701: f(x)= 10.671947807557636
# differential_evolution step 702: f(x)= 10.671947807557636
# differential_evolution step 703: f(x)= 10.671947807557636
# differential_evolution step 704: f(x)= 10.671947807557636
# differential_evolution step 705: f(x)= 10.671947807557636
# differential_evolution step 706: f(x)= 10.671947807557636
# differential_evolution step 707: f(x)= 10.671947807557636
# differential_evolution step 708: f(x)= 10.671947807557636
# differential_evolution step 709: f(x)= 10.671947807557636
# differential_evolution step 710: f(x)= 10.671947807557636
# differential_evolution step 711: f(x)= 10.671947807557636
# differential_evolution step 712: f(x)= 10.671947807557636
# differential_evolution step 713: f(x)= 10.671947807557636
# differential_evolution step 714: f(x)= 10.671947807557636
# differential_evolution step 715: f(x)= 10.671924080528362
# differential_evolution step 716: f(x)= 10.671924080528362
# differential_evolution step 717: f(x)= 10.671924080528362
# differential_evolution step 718: f(x)= 10.671924080528362
# differential_evolution step 719: f(x)= 10.671924080528362
# differential_evolution step 720: f(x)= 10.67190734401536
# differential_evolution step 721: f(x)= 10.67190734401536
# differential_evolution step 722: f(x)= 10.67190734401536
# differential_evolution step 723: f(x)= 10.67190734401536
# differential_evolution step 724: f(x)= 10.67190734401536
# differential_evolution step 725: f(x)= 10.67190734401536
# differential_evolution step 726: f(x)= 10.67190734401536
# differential_evolution step 727: f(x)= 10.67190734401536
# differential_evolution step 728: f(x)= 10.6718817119446
# differential_evolution step 729: f(x)= 10.6718817119446
# differential_evolution step 730: f(x)= 10.6718817119446
# differential_evolution step 731: f(x)= 10.6718817119446
# differential_evolution step 732: f(x)= 10.6718817119446
# differential_evolution step 733: f(x)= 10.6718817119446
# differential_evolution step 734: f(x)= 10.6718817119446
# differential_evolution step 735: f(x)= 10.6718817119446
# differential_evolution step 736: f(x)= 10.6718817119446
# differential_evolution step 737: f(x)= 10.6718817119446
# differential_evolution step 738: f(x)= 10.6718817119446
# differential_evolution step 739: f(x)= 10.6718817119446
# differential_evolution step 740: f(x)= 10.671858379247398
# differential_evolution step 741: f(x)= 10.671858379247398
# differential_evolution step 742: f(x)= 10.671858379247398
# differential_evolution step 743: f(x)= 10.671858379247398
# differential_evolution step 744: f(x)= 10.671858379247398
# differential_evolution step 745: f(x)= 10.671858379247398
# differential_evolution step 746: f(x)= 10.671858379247398
# differential_evolution step 747: f(x)= 10.671858379247398
# differential_evolution step 748: f(x)= 10.671858379247398
# differential_evolution step 749: f(x)= 10.671858379247398
# differential_evolution step 750: f(x)= 10.671847612285706
# differential_evolution step 751: f(x)= 10.671847612285706
# differential_evolution step 752: f(x)= 10.671847612285706
# differential_evolution step 753: f(x)= 10.671847612285706
# differential_evolution step 754: f(x)= 10.671847612285706
# differential_evolution step 755: f(x)= 10.671847612285706
# differential_evolution step 756: f(x)= 10.671847612285706
# differential_evolution step 757: f(x)= 10.671847612285706
# differential_evolution step 758: f(x)= 10.671847612285706
# differential_evolution step 759: f(x)= 10.671847612285706
# differential_evolution step 760: f(x)= 10.671847612285706
# differential_evolution step 761: f(x)= 10.671847612285706
# differential_evolution step 762: f(x)= 10.671847612285706
# differential_evolution step 763: f(x)= 10.671847612285706
# differential_evolution step 764: f(x)= 10.671847612285706
# differential_evolution step 765: f(x)= 10.671847612285706
# differential_evolution step 766: f(x)= 10.671847612285706
# differential_evolution step 767: f(x)= 10.671847612285706
# differential_evolution step 768: f(x)= 10.671847612285706
# differential_evolution step 769: f(x)= 10.671847612285706
# differential_evolution step 770: f(x)= 10.671847612285706
# differential_evolution step 771: f(x)= 10.671847612285706
# differential_evolution step 772: f(x)= 10.671847612285706
# differential_evolution step 773: f(x)= 10.671847612285706
# differential_evolution step 774: f(x)= 10.671847612285706
# differential_evolution step 775: f(x)= 10.671847612285706
# differential_evolution step 776: f(x)= 10.671847612285706
# differential_evolution step 777: f(x)= 10.671847612285706
# differential_evolution step 778: f(x)= 10.671847612285706
# differential_evolution step 779: f(x)= 10.671847612285706
# differential_evolution step 780: f(x)= 10.671847612285706
# differential_evolution step 781: f(x)= 10.671847612285706
# differential_evolution step 782: f(x)= 10.671847612285706
# differential_evolution step 783: f(x)= 10.671847612285706
# differential_evolution step 784: f(x)= 10.671847612285706
# differential_evolution step 785: f(x)= 10.671844376265913
# differential_evolution step 786: f(x)= 10.671844376265913
# differential_evolution step 787: f(x)= 10.671839891036143
# differential_evolution step 788: f(x)= 10.671839891036143
# differential_evolution step 789: f(x)= 10.671839891036143
# differential_evolution step 790: f(x)= 10.671834536437093
# differential_evolution step 791: f(x)= 10.671834536437093
# differential_evolution step 792: f(x)= 10.671834536437093
# differential_evolution step 793: f(x)= 10.67180821643807
# differential_evolution step 794: f(x)= 10.67180821643807
# differential_evolution step 795: f(x)= 10.67180821643807
# differential_evolution step 796: f(x)= 10.67180821643807
# differential_evolution step 797: f(x)= 10.67180821643807
# differential_evolution step 798: f(x)= 10.67180821643807
# differential_evolution step 799: f(x)= 10.67180821643807
# differential_evolution step 800: f(x)= 10.67180821643807
# differential_evolution step 801: f(x)= 10.67180821643807
# differential_evolution step 802: f(x)= 10.67180821643807
# differential_evolution step 803: f(x)= 10.67180821643807
# differential_evolution step 804: f(x)= 10.67180821643807
# differential_evolution step 805: f(x)= 10.67180821643807
# differential_evolution step 806: f(x)= 10.67180821643807
# differential_evolution step 807: f(x)= 10.67180821643807
# differential_evolution step 808: f(x)= 10.67180821643807
# differential_evolution step 809: f(x)= 10.67180821643807
# differential_evolution step 810: f(x)= 10.67180821643807
# differential_evolution step 811: f(x)= 10.67180821643807
# differential_evolution step 812: f(x)= 10.67180821643807
# differential_evolution step 813: f(x)= 10.67180821643807
# differential_evolution step 814: f(x)= 10.67180821643807
# differential_evolution step 815: f(x)= 10.67180821643807
# differential_evolution step 816: f(x)= 10.67180821643807
# differential_evolution step 817: f(x)= 10.67180821643807
# differential_evolution step 818: f(x)= 10.67180821643807
# differential_evolution step 819: f(x)= 10.67180821643807
# differential_evolution step 820: f(x)= 10.67180821643807
# differential_evolution step 821: f(x)= 10.67180821643807
# differential_evolution step 822: f(x)= 10.67180821643807
# differential_evolution step 823: f(x)= 10.67180821643807
# differential_evolution step 824: f(x)= 10.67180821643807
# differential_evolution step 825: f(x)= 10.67180821643807
# differential_evolution step 826: f(x)= 10.67180821643807
# differential_evolution step 827: f(x)= 10.67180821643807
# differential_evolution step 828: f(x)= 10.67180821643807
# differential_evolution step 829: f(x)= 10.67180821643807
# differential_evolution step 830: f(x)= 10.67180821643807
# differential_evolution step 831: f(x)= 10.67180821643807
# differential_evolution step 832: f(x)= 10.67180821643807
# differential_evolution step 833: f(x)= 10.67180821643807
# differential_evolution step 834: f(x)= 10.671805213693254
# differential_evolution step 835: f(x)= 10.67180466991449
# differential_evolution step 836: f(x)= 10.67180466991449
# differential_evolution step 837: f(x)= 10.67180466991449
# differential_evolution step 838: f(x)= 10.67180466991449
# differential_evolution step 839: f(x)= 10.67180466991449
# differential_evolution step 840: f(x)= 10.67180466991449
# differential_evolution step 841: f(x)= 10.67180466991449
# differential_evolution step 842: f(x)= 10.67180466991449
# differential_evolution step 843: f(x)= 10.67180466991449
# differential_evolution step 844: f(x)= 10.67180466991449
# differential_evolution step 845: f(x)= 10.671800912856648
# differential_evolution step 846: f(x)= 10.671800912856648
# differential_evolution step 847: f(x)= 10.671800912856648
# differential_evolution step 848: f(x)= 10.671800912856648
# differential_evolution step 849: f(x)= 10.671800912856648
# differential_evolution step 850: f(x)= 10.671800912856648
# differential_evolution step 851: f(x)= 10.671800912856648
# differential_evolution step 852: f(x)= 10.671800912856648
# differential_evolution step 853: f(x)= 10.671800912856648
# differential_evolution step 854: f(x)= 10.671800912856648
# differential_evolution step 855: f(x)= 10.671780403841034
# differential_evolution step 856: f(x)= 10.671780403841034
# differential_evolution step 857: f(x)= 10.671780403841034
# differential_evolution step 858: f(x)= 10.671780403841034
# differential_evolution step 859: f(x)= 10.671780403841034
# differential_evolution step 860: f(x)= 10.671780403841034
# differential_evolution step 861: f(x)= 10.671780403841034
# differential_evolution step 862: f(x)= 10.671780403841034
# differential_evolution step 863: f(x)= 10.671780403841034
# differential_evolution step 864: f(x)= 10.671780403841034
# differential_evolution step 865: f(x)= 10.671780403841034
# differential_evolution step 866: f(x)= 10.671780403841034
# differential_evolution step 867: f(x)= 10.671780403841034
# differential_evolution step 868: f(x)= 10.671780403841034
# differential_evolution step 869: f(x)= 10.671780403841034
# differential_evolution step 870: f(x)= 10.671780403841034
# differential_evolution step 871: f(x)= 10.671780403841034
# differential_evolution step 872: f(x)= 10.671780403841034
# differential_evolution step 873: f(x)= 10.671780403841034
# differential_evolution step 874: f(x)= 10.671780403841034
# differential_evolution step 875: f(x)= 10.671780403841034
# differential_evolution step 876: f(x)= 10.671780403841034
# differential_evolution step 877: f(x)= 10.671780403841034
# differential_evolution step 878: f(x)= 10.671780403841034
# differential_evolution step 879: f(x)= 10.671780403841034
# differential_evolution step 880: f(x)= 10.671780403841034
# differential_evolution step 881: f(x)= 10.671780403841034
# differential_evolution step 882: f(x)= 10.671780403841034
# differential_evolution step 883: f(x)= 10.671780403841034
# differential_evolution step 884: f(x)= 10.671780403841034
# differential_evolution step 885: f(x)= 10.671780403841034
# differential_evolution step 886: f(x)= 10.671780403841034
# differential_evolution step 887: f(x)= 10.671780403841034
# differential_evolution step 888: f(x)= 10.671780403841034
# differential_evolution step 889: f(x)= 10.671780403841034
# differential_evolution step 890: f(x)= 10.671780403841034
# differential_evolution step 891: f(x)= 10.671780403841034
# differential_evolution step 892: f(x)= 10.671780403841034
# differential_evolution step 893: f(x)= 10.671780403841034
# differential_evolution step 894: f(x)= 10.671780403841034
# differential_evolution step 895: f(x)= 10.671780403841034
# differential_evolution step 896: f(x)= 10.671780403841034
# differential_evolution step 897: f(x)= 10.671780403841034
# differential_evolution step 898: f(x)= 10.671780403841034
# differential_evolution step 899: f(x)= 10.671780403841034
# differential_evolution step 900: f(x)= 10.671780403841034
# differential_evolution step 901: f(x)= 10.671780403841034
# differential_evolution step 902: f(x)= 10.671780403841034
# differential_evolution step 903: f(x)= 10.671780403841034
# differential_evolution step 904: f(x)= 10.671780403841034
# differential_evolution step 905: f(x)= 10.671780403841034
# differential_evolution step 906: f(x)= 10.671780403841034
# differential_evolution step 907: f(x)= 10.671780403841034
# differential_evolution step 908: f(x)= 10.671780403841034
# differential_evolution step 909: f(x)= 10.671780403841034
# differential_evolution step 910: f(x)= 10.671780403841034
# differential_evolution step 911: f(x)= 10.671780403841034
# differential_evolution step 912: f(x)= 10.671780403841034
# differential_evolution step 913: f(x)= 10.671780403841034
# differential_evolution step 914: f(x)= 10.671780403841034
# differential_evolution step 915: f(x)= 10.671780403841034
# differential_evolution step 916: f(x)= 10.671780403841034
# differential_evolution step 917: f(x)= 10.671780403841034
# differential_evolution step 918: f(x)= 10.671780403841034
# differential_evolution step 919: f(x)= 10.671780403841034
# differential_evolution step 920: f(x)= 10.671780403841034
# differential_evolution step 921: f(x)= 10.671780403841034
# differential_evolution step 922: f(x)= 10.671780403841034
# differential_evolution step 923: f(x)= 10.671780403841034
# differential_evolution step 924: f(x)= 10.671780403841034
# differential_evolution step 925: f(x)= 10.671780403841034
# differential_evolution step 926: f(x)= 10.671780403841034
# differential_evolution step 927: f(x)= 10.671780403841034
# differential_evolution step 928: f(x)= 10.671780403841034
# differential_evolution step 929: f(x)= 10.671780403841034
# differential_evolution step 930: f(x)= 10.671780403841034
# differential_evolution step 931: f(x)= 10.671780403841034
# differential_evolution step 932: f(x)= 10.671780042477998
# differential_evolution step 933: f(x)= 10.671780042477998
# differential_evolution step 934: f(x)= 10.671780007765426
# differential_evolution step 935: f(x)= 10.671780007765426
# differential_evolution step 936: f(x)= 10.671780007765426
# differential_evolution step 937: f(x)= 10.671780007765426
# differential_evolution step 938: f(x)= 10.671780007765426
# differential_evolution step 939: f(x)= 10.671780007765426
# differential_evolution step 940: f(x)= 10.671780007765426
# differential_evolution step 941: f(x)= 10.671780007765426
# differential_evolution step 942: f(x)= 10.671780007765426
# differential_evolution step 943: f(x)= 10.671780007765426
# differential_evolution step 944: f(x)= 10.671780007765426
# differential_evolution step 945: f(x)= 10.671778724315859
# differential_evolution step 946: f(x)= 10.671778724315859
# differential_evolution step 947: f(x)= 10.671778724315859
# differential_evolution step 948: f(x)= 10.671778724315859
# differential_evolution step 949: f(x)= 10.671777044300732
# differential_evolution step 950: f(x)= 10.671776693731037
# differential_evolution step 951: f(x)= 10.671776693731037
# differential_evolution step 952: f(x)= 10.671776693731037
# differential_evolution step 953: f(x)= 10.671776693731037
# differential_evolution step 954: f(x)= 10.671776693731037
# differential_evolution step 955: f(x)= 10.671775502547618
# differential_evolution step 956: f(x)= 10.671775502547618
# differential_evolution step 957: f(x)= 10.671775502547618
# differential_evolution step 958: f(x)= 10.671775502547618
# differential_evolution step 959: f(x)= 10.671775502547618
# differential_evolution step 960: f(x)= 10.671775502547618
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=8.0727, r_e=3.0179, n=0.8114, x_0=39.9238
# Sérsic 2: I_e=0.6142, r_e=16.3697, n=1.4429, x_0=48.9053
# Sérsic 3: I_e=1.1700, r_e=3.0029, n=1.0906, x_0=58.2465
# Chi quadro minimo: 10.67177068248343
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, radial_profile_error_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=7.7767, r_e=3.1465, n=0.8381, x_0=40.0041
# Sérsic 2: I_e=0.4213, r_e=18.8719, n=1.6967, x_0=49.0074
# Sérsic 3: I_e=0.9885, r_e=3.7679, n=1.2017, x_0=58.2465
# [0.51802398 0.13891578 0.05139166 0.03382436 0.10923468 2.77470058
#  0.1858263  0.14011934 0.3971835  1.13176246 0.30194723 0.10151652]
# 17.318457309548524

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2563.195160084104
# differential_evolution step 2: f(x)= 2563.195160084104
# differential_evolution step 3: f(x)= 787.697873885205
# differential_evolution step 4: f(x)= 633.6891090885597
# differential_evolution step 5: f(x)= 633.6891090885597
# differential_evolution step 6: f(x)= 633.6891090885597
# differential_evolution step 7: f(x)= 633.6891090885597
# differential_evolution step 8: f(x)= 633.6891090885597
# differential_evolution step 9: f(x)= 633.6891090885597
# differential_evolution step 10: f(x)= 633.6891090885597
# differential_evolution step 11: f(x)= 633.6891090885597
# differential_evolution step 12: f(x)= 633.6891090885597
# differential_evolution step 13: f(x)= 633.6891090885597
# differential_evolution step 14: f(x)= 633.6891090885597
# differential_evolution step 15: f(x)= 633.6891090885597
# differential_evolution step 16: f(x)= 633.6891090885597
# differential_evolution step 17: f(x)= 553.2712120849861
# differential_evolution step 18: f(x)= 553.2712120849861
# differential_evolution step 19: f(x)= 468.0499258149823
# differential_evolution step 20: f(x)= 468.0499258149823
# differential_evolution step 21: f(x)= 468.0499258149823
# differential_evolution step 22: f(x)= 425.69747189339506
# differential_evolution step 23: f(x)= 425.69747189339506
# differential_evolution step 24: f(x)= 335.0614373493131
# differential_evolution step 25: f(x)= 335.0614373493131
# differential_evolution step 26: f(x)= 335.0614373493131
# differential_evolution step 27: f(x)= 335.0614373493131
# differential_evolution step 28: f(x)= 335.0614373493131
# differential_evolution step 29: f(x)= 328.177542016772
# differential_evolution step 30: f(x)= 328.177542016772
# differential_evolution step 31: f(x)= 328.177542016772
# differential_evolution step 32: f(x)= 257.96158923232383
# differential_evolution step 33: f(x)= 247.44074169873485
# differential_evolution step 34: f(x)= 232.07879800244302
# differential_evolution step 35: f(x)= 232.07879800244302
# differential_evolution step 36: f(x)= 232.07879800244302
# differential_evolution step 37: f(x)= 232.07879800244302
# differential_evolution step 38: f(x)= 232.07879800244302
# differential_evolution step 39: f(x)= 154.13154442171006
# differential_evolution step 40: f(x)= 154.13154442171006
# differential_evolution step 41: f(x)= 154.13154442171006
# differential_evolution step 42: f(x)= 144.0410804858647
# differential_evolution step 43: f(x)= 144.0410804858647
# differential_evolution step 44: f(x)= 144.0410804858647
# differential_evolution step 45: f(x)= 144.0410804858647
# differential_evolution step 46: f(x)= 144.0410804858647
# differential_evolution step 47: f(x)= 144.0410804858647
# differential_evolution step 48: f(x)= 144.0410804858647
# differential_evolution step 49: f(x)= 144.0410804858647
# differential_evolution step 50: f(x)= 144.0410804858647
# differential_evolution step 51: f(x)= 144.0410804858647
# differential_evolution step 52: f(x)= 144.0410804858647
# differential_evolution step 53: f(x)= 144.0410804858647
# differential_evolution step 54: f(x)= 144.0410804858647
# differential_evolution step 55: f(x)= 144.0410804858647
# differential_evolution step 56: f(x)= 144.0410804858647
# differential_evolution step 57: f(x)= 144.0410804858647
# differential_evolution step 58: f(x)= 126.88946940454258
# differential_evolution step 59: f(x)= 126.88946940454258
# differential_evolution step 60: f(x)= 126.88946940454258
# differential_evolution step 61: f(x)= 126.88946940454258
# differential_evolution step 62: f(x)= 126.88946940454258
# differential_evolution step 63: f(x)= 126.88946940454258
# differential_evolution step 64: f(x)= 126.88946940454258
# differential_evolution step 65: f(x)= 126.88946940454258
# differential_evolution step 66: f(x)= 126.88946940454258
# differential_evolution step 67: f(x)= 126.88946940454258
# differential_evolution step 68: f(x)= 126.88946940454258
# differential_evolution step 69: f(x)= 126.88946940454258
# differential_evolution step 70: f(x)= 123.21222580463092
# differential_evolution step 71: f(x)= 123.21222580463092
# differential_evolution step 72: f(x)= 123.21222580463092
# differential_evolution step 73: f(x)= 123.21222580463092
# differential_evolution step 74: f(x)= 116.56825187654061
# differential_evolution step 75: f(x)= 115.57212588587468
# differential_evolution step 76: f(x)= 115.57212588587468
# differential_evolution step 77: f(x)= 115.57212588587468
# differential_evolution step 78: f(x)= 115.57212588587468
# differential_evolution step 79: f(x)= 115.57212588587468
# differential_evolution step 80: f(x)= 115.57212588587468
# differential_evolution step 81: f(x)= 115.57212588587468
# differential_evolution step 82: f(x)= 115.57212588587468
# differential_evolution step 83: f(x)= 115.57212588587468
# differential_evolution step 84: f(x)= 115.57212588587468
# differential_evolution step 85: f(x)= 115.57212588587468
# differential_evolution step 86: f(x)= 115.57212588587468
# differential_evolution step 87: f(x)= 101.38624061905475
# differential_evolution step 88: f(x)= 101.38624061905475
# differential_evolution step 89: f(x)= 101.38624061905475
# differential_evolution step 90: f(x)= 101.38624061905475
# differential_evolution step 91: f(x)= 100.6110324817027
# differential_evolution step 92: f(x)= 100.6110324817027
# differential_evolution step 93: f(x)= 100.6110324817027
# differential_evolution step 94: f(x)= 100.6110324817027
# differential_evolution step 95: f(x)= 100.6110324817027
# differential_evolution step 96: f(x)= 100.6110324817027
# differential_evolution step 97: f(x)= 100.6110324817027
# differential_evolution step 98: f(x)= 100.6110324817027
# differential_evolution step 99: f(x)= 100.6110324817027
# differential_evolution step 100: f(x)= 97.90272134864703
# differential_evolution step 101: f(x)= 97.90272134864703
# differential_evolution step 102: f(x)= 97.90272134864703
# differential_evolution step 103: f(x)= 97.90272134864703
# differential_evolution step 104: f(x)= 97.90272134864703
# differential_evolution step 105: f(x)= 97.90272134864703
# differential_evolution step 106: f(x)= 97.90272134864703
# differential_evolution step 107: f(x)= 97.63821357007883
# differential_evolution step 108: f(x)= 97.63821357007883
# differential_evolution step 109: f(x)= 97.63821357007883
# differential_evolution step 110: f(x)= 97.63821357007883
# differential_evolution step 111: f(x)= 97.63821357007883
# differential_evolution step 112: f(x)= 97.63821357007883
# differential_evolution step 113: f(x)= 93.75839366621159
# differential_evolution step 114: f(x)= 93.75839366621159
# differential_evolution step 115: f(x)= 93.75839366621159
# differential_evolution step 116: f(x)= 91.98056684411453
# differential_evolution step 117: f(x)= 91.98056684411453
# differential_evolution step 118: f(x)= 91.98056684411453
# differential_evolution step 119: f(x)= 91.98056684411453
# differential_evolution step 120: f(x)= 91.98056684411453
# differential_evolution step 121: f(x)= 91.98056684411453
# differential_evolution step 122: f(x)= 91.47848754539677
# differential_evolution step 123: f(x)= 91.47848754539677
# differential_evolution step 124: f(x)= 83.80428545119094
# differential_evolution step 125: f(x)= 83.80428545119094
# differential_evolution step 126: f(x)= 83.80428545119094
# differential_evolution step 127: f(x)= 83.80428545119094
# differential_evolution step 128: f(x)= 83.80428545119094
# differential_evolution step 129: f(x)= 83.80428545119094
# differential_evolution step 130: f(x)= 83.80428545119094
# differential_evolution step 131: f(x)= 83.80428545119094
# differential_evolution step 132: f(x)= 82.93664605709202
# differential_evolution step 133: f(x)= 82.93664605709202
# differential_evolution step 134: f(x)= 82.93664605709202
# differential_evolution step 135: f(x)= 82.93664605709202
# differential_evolution step 136: f(x)= 82.93664605709202
# differential_evolution step 137: f(x)= 82.93664605709202
# differential_evolution step 138: f(x)= 82.93664605709202
# differential_evolution step 139: f(x)= 82.93664605709202
# differential_evolution step 140: f(x)= 82.93664605709202
# differential_evolution step 141: f(x)= 82.93664605709202
# differential_evolution step 142: f(x)= 82.93664605709202
# differential_evolution step 143: f(x)= 82.93664605709202
# differential_evolution step 144: f(x)= 82.93664605709202
# differential_evolution step 145: f(x)= 82.93664605709202
# differential_evolution step 146: f(x)= 82.93664605709202
# differential_evolution step 147: f(x)= 81.10450613194365
# differential_evolution step 148: f(x)= 81.10450613194365
# differential_evolution step 149: f(x)= 81.10450613194365
# differential_evolution step 150: f(x)= 81.10450613194365
# differential_evolution step 151: f(x)= 81.10450613194365
# differential_evolution step 152: f(x)= 81.10450613194365
# differential_evolution step 153: f(x)= 81.10450613194365
# differential_evolution step 154: f(x)= 80.67649347865589
# differential_evolution step 155: f(x)= 80.67649347865589
# differential_evolution step 156: f(x)= 80.67649347865589
# differential_evolution step 157: f(x)= 80.67649347865589
# differential_evolution step 158: f(x)= 80.67649347865589
# differential_evolution step 159: f(x)= 80.67649347865589
# differential_evolution step 160: f(x)= 80.67649347865589
# differential_evolution step 161: f(x)= 80.67649347865589
# differential_evolution step 162: f(x)= 80.67649347865589
# differential_evolution step 163: f(x)= 80.67649347865589
# differential_evolution step 164: f(x)= 80.67649347865589
# differential_evolution step 165: f(x)= 78.60877344839842
# differential_evolution step 166: f(x)= 78.60877344839842
# differential_evolution step 167: f(x)= 78.60877344839842
# differential_evolution step 168: f(x)= 78.60877344839842
# differential_evolution step 169: f(x)= 78.60877344839842
# differential_evolution step 170: f(x)= 78.60877344839842
# differential_evolution step 171: f(x)= 78.60877344839842
# differential_evolution step 172: f(x)= 78.60877344839842
# differential_evolution step 173: f(x)= 78.60877344839842
# differential_evolution step 174: f(x)= 78.60877344839842
# differential_evolution step 175: f(x)= 78.60877344839842
# differential_evolution step 176: f(x)= 78.60877344839842
# differential_evolution step 177: f(x)= 78.60877344839842
# differential_evolution step 178: f(x)= 77.99673567006678
# differential_evolution step 179: f(x)= 77.99673567006678
# differential_evolution step 180: f(x)= 77.99673567006678
# differential_evolution step 181: f(x)= 77.99673567006678
# differential_evolution step 182: f(x)= 77.99673567006678
# differential_evolution step 183: f(x)= 77.99673567006678
# differential_evolution step 184: f(x)= 77.99673567006678
# differential_evolution step 185: f(x)= 77.99673567006678
# differential_evolution step 186: f(x)= 77.36189807392068
# differential_evolution step 187: f(x)= 77.36189807392068
# differential_evolution step 188: f(x)= 77.36189807392068
# differential_evolution step 189: f(x)= 77.36189807392068
# differential_evolution step 190: f(x)= 77.36189807392068
# differential_evolution step 191: f(x)= 77.36189807392068
# differential_evolution step 192: f(x)= 77.36189807392068
# differential_evolution step 193: f(x)= 77.36189807392068
# differential_evolution step 194: f(x)= 77.36189807392068
# differential_evolution step 195: f(x)= 77.36189807392068
# differential_evolution step 196: f(x)= 77.36189807392068
# differential_evolution step 197: f(x)= 77.36189807392068
# differential_evolution step 198: f(x)= 77.36189807392068
# differential_evolution step 199: f(x)= 77.36189807392068
# differential_evolution step 200: f(x)= 77.36189807392068
# differential_evolution step 201: f(x)= 77.36189807392068
# differential_evolution step 202: f(x)= 77.36189807392068
# differential_evolution step 203: f(x)= 77.36189807392068
# differential_evolution step 204: f(x)= 77.36189807392068
# differential_evolution step 205: f(x)= 77.36189807392068
# differential_evolution step 206: f(x)= 77.03030302534422
# differential_evolution step 207: f(x)= 77.03030302534422
# differential_evolution step 208: f(x)= 76.9599337142639
# differential_evolution step 209: f(x)= 76.9599337142639
# differential_evolution step 210: f(x)= 76.9599337142639
# differential_evolution step 211: f(x)= 76.9599337142639
# differential_evolution step 212: f(x)= 76.9599337142639
# differential_evolution step 213: f(x)= 76.9599337142639
# differential_evolution step 214: f(x)= 76.9599337142639
# differential_evolution step 215: f(x)= 76.9599337142639
# differential_evolution step 216: f(x)= 76.9599337142639
# differential_evolution step 217: f(x)= 76.9599337142639
# differential_evolution step 218: f(x)= 76.61496980493341
# differential_evolution step 219: f(x)= 76.61496980493341
# differential_evolution step 220: f(x)= 76.61496980493341
# differential_evolution step 221: f(x)= 76.1198331821549
# differential_evolution step 222: f(x)= 76.1198331821549
# differential_evolution step 223: f(x)= 76.1198331821549
# differential_evolution step 224: f(x)= 76.1198331821549
# differential_evolution step 225: f(x)= 76.1198331821549
# differential_evolution step 226: f(x)= 76.1198331821549
# differential_evolution step 227: f(x)= 76.1198331821549
# differential_evolution step 228: f(x)= 76.1198331821549
# differential_evolution step 229: f(x)= 76.1198331821549
# differential_evolution step 230: f(x)= 76.1198331821549
# differential_evolution step 231: f(x)= 76.1198331821549
# differential_evolution step 232: f(x)= 76.1198331821549
# differential_evolution step 233: f(x)= 76.1198331821549
# differential_evolution step 234: f(x)= 76.1198331821549
# differential_evolution step 235: f(x)= 76.1198331821549
# differential_evolution step 236: f(x)= 76.1198331821549
# differential_evolution step 237: f(x)= 76.1198331821549
# differential_evolution step 238: f(x)= 76.1198331821549
# differential_evolution step 239: f(x)= 76.1198331821549
# differential_evolution step 240: f(x)= 76.1198331821549
# differential_evolution step 241: f(x)= 76.1198331821549
# differential_evolution step 242: f(x)= 76.1198331821549
# differential_evolution step 243: f(x)= 76.1198331821549
# differential_evolution step 244: f(x)= 76.1198331821549
# differential_evolution step 245: f(x)= 76.1198331821549
# differential_evolution step 246: f(x)= 76.1198331821549
# differential_evolution step 247: f(x)= 76.1198331821549
# differential_evolution step 248: f(x)= 76.1198331821549
# differential_evolution step 249: f(x)= 76.06064899310863
# differential_evolution step 250: f(x)= 76.06064899310863
# differential_evolution step 251: f(x)= 76.06064899310863
# differential_evolution step 252: f(x)= 76.06064899310863
# differential_evolution step 253: f(x)= 76.06064899310863
# differential_evolution step 254: f(x)= 76.06064899310863
# differential_evolution step 255: f(x)= 76.06064899310863
# differential_evolution step 256: f(x)= 76.06064899310863
# differential_evolution step 257: f(x)= 76.06064899310863
# differential_evolution step 258: f(x)= 76.06064899310863
# differential_evolution step 259: f(x)= 76.06064899310863
# differential_evolution step 260: f(x)= 76.06064899310863
# differential_evolution step 261: f(x)= 76.06064899310863
# differential_evolution step 262: f(x)= 76.06064899310863
# differential_evolution step 263: f(x)= 76.06064899310863
# differential_evolution step 264: f(x)= 76.06064899310863
# differential_evolution step 265: f(x)= 76.06064899310863
# differential_evolution step 266: f(x)= 76.06064899310863
# differential_evolution step 267: f(x)= 76.06064899310863
# differential_evolution step 268: f(x)= 76.06064899310863
# differential_evolution step 269: f(x)= 76.03698813261823
# differential_evolution step 270: f(x)= 76.03698813261823
# differential_evolution step 271: f(x)= 76.03698813261823
# differential_evolution step 272: f(x)= 76.03698813261823
# differential_evolution step 273: f(x)= 76.03698813261823
# differential_evolution step 274: f(x)= 76.03698813261823
# differential_evolution step 275: f(x)= 76.03698813261823
# differential_evolution step 276: f(x)= 76.03698813261823
# differential_evolution step 277: f(x)= 76.03698813261823
# differential_evolution step 278: f(x)= 76.01749289237945
# differential_evolution step 279: f(x)= 76.01749289237945
# differential_evolution step 280: f(x)= 76.01749289237945
# differential_evolution step 281: f(x)= 76.01749289237945
# differential_evolution step 282: f(x)= 76.01749289237945
# differential_evolution step 283: f(x)= 76.01749289237945
# differential_evolution step 284: f(x)= 76.01749289237945
# differential_evolution step 285: f(x)= 76.01749289237945
# differential_evolution step 286: f(x)= 76.01749289237945
# differential_evolution step 287: f(x)= 76.01749289237945
# differential_evolution step 288: f(x)= 75.9809586444404
# differential_evolution step 289: f(x)= 75.9809586444404
# differential_evolution step 290: f(x)= 75.9809586444404
# differential_evolution step 291: f(x)= 75.96185492444198
# differential_evolution step 292: f(x)= 75.90997059711084
# differential_evolution step 293: f(x)= 75.90997059711084
# differential_evolution step 294: f(x)= 75.90997059711084
# differential_evolution step 295: f(x)= 75.90997059711084
# differential_evolution step 296: f(x)= 75.90997059711084
# differential_evolution step 297: f(x)= 75.90997059711084
# differential_evolution step 298: f(x)= 75.90997059711084
# differential_evolution step 299: f(x)= 75.90997059711084
# differential_evolution step 300: f(x)= 75.90997059711084
# differential_evolution step 301: f(x)= 75.90997059711084
# differential_evolution step 302: f(x)= 75.90997059711084
# differential_evolution step 303: f(x)= 75.90997059711084
# differential_evolution step 304: f(x)= 75.90353654194121
# differential_evolution step 305: f(x)= 75.90353654194121
# differential_evolution step 306: f(x)= 75.90353654194121
# differential_evolution step 307: f(x)= 75.90243388188185
# differential_evolution step 308: f(x)= 75.90243388188185
# differential_evolution step 309: f(x)= 75.90243388188185
# differential_evolution step 310: f(x)= 75.90243388188185
# differential_evolution step 311: f(x)= 75.90243388188185
# differential_evolution step 312: f(x)= 75.90142553865557
# differential_evolution step 313: f(x)= 75.90142553865557
# differential_evolution step 314: f(x)= 75.86743625019058
# differential_evolution step 315: f(x)= 75.86743625019058
# differential_evolution step 316: f(x)= 75.86743625019058
# differential_evolution step 317: f(x)= 75.86743625019058
# differential_evolution step 318: f(x)= 75.86743625019058
# differential_evolution step 319: f(x)= 75.86743625019058
# differential_evolution step 320: f(x)= 75.86743625019058
# differential_evolution step 321: f(x)= 75.86743625019058
# differential_evolution step 322: f(x)= 75.86743625019058
# differential_evolution step 323: f(x)= 75.86743625019058
# differential_evolution step 324: f(x)= 75.86743625019058
# differential_evolution step 325: f(x)= 75.86743625019058
# differential_evolution step 326: f(x)= 75.86743625019058
# differential_evolution step 327: f(x)= 75.86743625019058
# differential_evolution step 328: f(x)= 75.86397222730788
# differential_evolution step 329: f(x)= 75.86397222730788
# differential_evolution step 330: f(x)= 75.86397222730788
# differential_evolution step 331: f(x)= 75.86397222730788
# differential_evolution step 332: f(x)= 75.86397222730788
# differential_evolution step 333: f(x)= 75.86397222730788
# differential_evolution step 334: f(x)= 75.86397222730788
# differential_evolution step 335: f(x)= 75.86397222730788
# differential_evolution step 336: f(x)= 75.86397222730788
# differential_evolution step 337: f(x)= 75.86397222730788
# differential_evolution step 338: f(x)= 75.86397222730788
# differential_evolution step 339: f(x)= 75.86397222730788
# differential_evolution step 340: f(x)= 75.85835929086328
# differential_evolution step 341: f(x)= 75.85835929086328
# differential_evolution step 342: f(x)= 75.85835929086328
# differential_evolution step 343: f(x)= 75.85835929086328
# differential_evolution step 344: f(x)= 75.85835929086328
# differential_evolution step 345: f(x)= 75.85835929086328
# differential_evolution step 346: f(x)= 75.85517622257859
# differential_evolution step 347: f(x)= 75.85517622257859
# differential_evolution step 348: f(x)= 75.85168461503521
# differential_evolution step 349: f(x)= 75.84997061095504
# differential_evolution step 350: f(x)= 75.84997061095504
# differential_evolution step 351: f(x)= 75.84997061095504
# differential_evolution step 352: f(x)= 75.84997061095504
# differential_evolution step 353: f(x)= 75.84997061095504
# differential_evolution step 354: f(x)= 75.84997061095504
# differential_evolution step 355: f(x)= 75.84997061095504
# differential_evolution step 356: f(x)= 75.84997061095504
# differential_evolution step 357: f(x)= 75.84075632723662
# differential_evolution step 358: f(x)= 75.84075632723662
# differential_evolution step 359: f(x)= 75.84075632723662
# differential_evolution step 360: f(x)= 75.84075632723662
# differential_evolution step 361: f(x)= 75.84075632723662
# differential_evolution step 362: f(x)= 75.84075632723662
# differential_evolution step 363: f(x)= 75.84075632723662
# differential_evolution step 364: f(x)= 75.84075632723662
# differential_evolution step 365: f(x)= 75.84075632723662
# differential_evolution step 366: f(x)= 75.84010923592713
# differential_evolution step 367: f(x)= 75.84010923592713
# differential_evolution step 368: f(x)= 75.84010923592713
# differential_evolution step 369: f(x)= 75.84010923592713
# differential_evolution step 370: f(x)= 75.84010923592713
# differential_evolution step 371: f(x)= 75.84010923592713
# differential_evolution step 372: f(x)= 75.84010923592713
# differential_evolution step 373: f(x)= 75.84010923592713
# differential_evolution step 374: f(x)= 75.84010923592713
# differential_evolution step 375: f(x)= 75.84010923592713
# differential_evolution step 376: f(x)= 75.83875526859441
# differential_evolution step 377: f(x)= 75.83804771176423
# differential_evolution step 378: f(x)= 75.83804771176423
# differential_evolution step 379: f(x)= 75.83804771176423
# differential_evolution step 380: f(x)= 75.83804771176423
# differential_evolution step 381: f(x)= 75.83804771176423
# differential_evolution step 382: f(x)= 75.83804771176423
# differential_evolution step 383: f(x)= 75.83804771176423
# differential_evolution step 384: f(x)= 75.83804771176423
# differential_evolution step 385: f(x)= 75.83804771176423
# differential_evolution step 386: f(x)= 75.83790085225328
# differential_evolution step 387: f(x)= 75.83790085225328
# differential_evolution step 388: f(x)= 75.83790085225328
# differential_evolution step 389: f(x)= 75.83790085225328
# differential_evolution step 390: f(x)= 75.83790085225328
# differential_evolution step 391: f(x)= 75.83545958807355
# differential_evolution step 392: f(x)= 75.83545958807355
# differential_evolution step 393: f(x)= 75.83545958807355
# differential_evolution step 394: f(x)= 75.83545958807355
# differential_evolution step 395: f(x)= 75.83545958807355
# differential_evolution step 396: f(x)= 75.83545958807355
# differential_evolution step 397: f(x)= 75.83545958807355
# differential_evolution step 398: f(x)= 75.83545958807355
# differential_evolution step 399: f(x)= 75.83545958807355
# differential_evolution step 400: f(x)= 75.83545958807355
# differential_evolution step 401: f(x)= 75.83545958807355
# differential_evolution step 402: f(x)= 75.83545958807355
# differential_evolution step 403: f(x)= 75.83545958807355
# differential_evolution step 404: f(x)= 75.83545958807355
# differential_evolution step 405: f(x)= 75.83545958807355
# differential_evolution step 406: f(x)= 75.83545958807355
# differential_evolution step 407: f(x)= 75.83545958807355
# differential_evolution step 408: f(x)= 75.83465513077545
# differential_evolution step 409: f(x)= 75.83465513077545
# differential_evolution step 410: f(x)= 75.83439554245649
# differential_evolution step 411: f(x)= 75.83439554245649
# differential_evolution step 412: f(x)= 75.83439554245649
# differential_evolution step 413: f(x)= 75.83439554245649
# differential_evolution step 414: f(x)= 75.83439554245649
# differential_evolution step 415: f(x)= 75.83439554245649
# differential_evolution step 416: f(x)= 75.83439554245649
# differential_evolution step 417: f(x)= 75.83439554245649
# differential_evolution step 418: f(x)= 75.83421289137029
# differential_evolution step 419: f(x)= 75.83421289137029
# differential_evolution step 420: f(x)= 75.83421289137029
# differential_evolution step 421: f(x)= 75.83403077043259
# differential_evolution step 422: f(x)= 75.8326383408566
# differential_evolution step 423: f(x)= 75.8326383408566
# differential_evolution step 424: f(x)= 75.8326383408566
# differential_evolution step 425: f(x)= 75.8326383408566
# differential_evolution step 426: f(x)= 75.8326383408566
# differential_evolution step 427: f(x)= 75.8326383408566
# differential_evolution step 428: f(x)= 75.83201146938599
# differential_evolution step 429: f(x)= 75.83201146938599
# differential_evolution step 430: f(x)= 75.83201146938599
# differential_evolution step 431: f(x)= 75.83201146938599
# differential_evolution step 432: f(x)= 75.83201146938599
# differential_evolution step 433: f(x)= 75.83201146938599
# differential_evolution step 434: f(x)= 75.83201146938599
# differential_evolution step 435: f(x)= 75.83201146938599
# differential_evolution step 436: f(x)= 75.83201146938599
# differential_evolution step 437: f(x)= 75.83201146938599
# differential_evolution step 438: f(x)= 75.83201146938599
# differential_evolution step 439: f(x)= 75.83201146938599
# differential_evolution step 440: f(x)= 75.83192041912477
# differential_evolution step 441: f(x)= 75.83192041912477
# differential_evolution step 442: f(x)= 75.83192041912477
# differential_evolution step 443: f(x)= 75.83192041912477
# differential_evolution step 444: f(x)= 75.83192041912477
# differential_evolution step 445: f(x)= 75.83192041912477
# differential_evolution step 446: f(x)= 75.83192041912477
# differential_evolution step 447: f(x)= 75.83192041912477
# differential_evolution step 448: f(x)= 75.83191032950131
# differential_evolution step 449: f(x)= 75.83191032950131
# differential_evolution step 450: f(x)= 75.83191032950131
# differential_evolution step 451: f(x)= 75.83191032950131
# differential_evolution step 452: f(x)= 75.83185918732991
# differential_evolution step 453: f(x)= 75.83185918732991
# differential_evolution step 454: f(x)= 75.83185918732991
# differential_evolution step 455: f(x)= 75.83185918732991
# differential_evolution step 456: f(x)= 75.83169701517623
# differential_evolution step 457: f(x)= 75.83169701517623
# differential_evolution step 458: f(x)= 75.83169701517623
# differential_evolution step 459: f(x)= 75.83161483981398
# differential_evolution step 460: f(x)= 75.83161483981398
# differential_evolution step 461: f(x)= 75.83161483981398
# differential_evolution step 462: f(x)= 75.83152909544513
# differential_evolution step 463: f(x)= 75.83152909544513
# differential_evolution step 464: f(x)= 75.83152909544513
# differential_evolution step 465: f(x)= 75.83152909544513
# differential_evolution step 466: f(x)= 75.83152909544513
# differential_evolution step 467: f(x)= 75.83152909544513
# differential_evolution step 468: f(x)= 75.83152909544513
# differential_evolution step 469: f(x)= 75.83152909544513
# differential_evolution step 470: f(x)= 75.83152909544513
# differential_evolution step 471: f(x)= 75.83152909544513
# differential_evolution step 472: f(x)= 75.83152909544513
# differential_evolution step 473: f(x)= 75.83152909544513
# differential_evolution step 474: f(x)= 75.83143702975994
# differential_evolution step 475: f(x)= 75.83143702975994
# differential_evolution step 476: f(x)= 75.83143702975994
# differential_evolution step 477: f(x)= 75.83143702975994
# differential_evolution step 478: f(x)= 75.83143702975994
# differential_evolution step 479: f(x)= 75.83143702975994
# differential_evolution step 480: f(x)= 75.83143702975994
# differential_evolution step 481: f(x)= 75.83143702975994
# differential_evolution step 482: f(x)= 75.83143702975994
# differential_evolution step 483: f(x)= 75.83143702975994
# differential_evolution step 484: f(x)= 75.83143702975994
# differential_evolution step 485: f(x)= 75.83143702975994
# differential_evolution step 486: f(x)= 75.83143702975994
# differential_evolution step 487: f(x)= 75.83143702975994
# differential_evolution step 488: f(x)= 75.83143702975994
# differential_evolution step 489: f(x)= 75.8312999155547
# differential_evolution step 490: f(x)= 75.8312999155547
# differential_evolution step 491: f(x)= 75.8312999155547
# differential_evolution step 492: f(x)= 75.8312999155547
# differential_evolution step 493: f(x)= 75.8312999155547
# differential_evolution step 494: f(x)= 75.83125468745594
# differential_evolution step 495: f(x)= 75.83125468745594
# differential_evolution step 496: f(x)= 75.83125468745594
# differential_evolution step 497: f(x)= 75.83125468745594
# differential_evolution step 498: f(x)= 75.83125468745594
# differential_evolution step 499: f(x)= 75.83125468745594
# differential_evolution step 500: f(x)= 75.83125468745594
# differential_evolution step 501: f(x)= 75.83119574209042
# differential_evolution step 502: f(x)= 75.83119574209042
# differential_evolution step 503: f(x)= 75.83119574209042
# differential_evolution step 504: f(x)= 75.83119574209042
# differential_evolution step 505: f(x)= 75.83119574209042
# differential_evolution step 506: f(x)= 75.83119574209042
# differential_evolution step 507: f(x)= 75.83119574209042
# differential_evolution step 508: f(x)= 75.83119574209042
# differential_evolution step 509: f(x)= 75.83118703645707
# differential_evolution step 510: f(x)= 75.83118703645707
# differential_evolution step 511: f(x)= 75.83118703645707
# differential_evolution step 512: f(x)= 75.83118703645707
# differential_evolution step 513: f(x)= 75.83118703645707
# differential_evolution step 514: f(x)= 75.83118703645707
# differential_evolution step 515: f(x)= 75.83118703645707
# differential_evolution step 516: f(x)= 75.83118703645707
# differential_evolution step 517: f(x)= 75.83115733172073
# differential_evolution step 518: f(x)= 75.83115733172073
# differential_evolution step 519: f(x)= 75.83115733172073
# differential_evolution step 520: f(x)= 75.83115733172073
# differential_evolution step 521: f(x)= 75.83115733172073
# differential_evolution step 522: f(x)= 75.83115733172073
# differential_evolution step 523: f(x)= 75.83115733172073
# differential_evolution step 524: f(x)= 75.83115733172073
# differential_evolution step 525: f(x)= 75.83115733172073
# differential_evolution step 526: f(x)= 75.83115733172073
# differential_evolution step 527: f(x)= 75.83115733172073
# differential_evolution step 528: f(x)= 75.83115733172073
# differential_evolution step 529: f(x)= 75.83115733172073
# differential_evolution step 530: f(x)= 75.83115733172073
# differential_evolution step 531: f(x)= 75.83109790888489
# differential_evolution step 532: f(x)= 75.83109790888489
# differential_evolution step 533: f(x)= 75.83109790888489
# differential_evolution step 534: f(x)= 75.83109790888489
# differential_evolution step 535: f(x)= 75.83109790888489
# differential_evolution step 536: f(x)= 75.83109648858841
# differential_evolution step 537: f(x)= 75.83109648858841
# differential_evolution step 538: f(x)= 75.83109648858841
# differential_evolution step 539: f(x)= 75.8310790296868
# differential_evolution step 540: f(x)= 75.8310790296868
# differential_evolution step 541: f(x)= 75.8310790296868
# differential_evolution step 542: f(x)= 75.8310790296868
# differential_evolution step 543: f(x)= 75.83107223470385
# differential_evolution step 544: f(x)= 75.83104796075001
# differential_evolution step 545: f(x)= 75.83103569418248
# differential_evolution step 546: f(x)= 75.83103569418248
# differential_evolution step 547: f(x)= 75.83103569418248
# differential_evolution step 548: f(x)= 75.83103569418248
# differential_evolution step 549: f(x)= 75.83103569418248
# differential_evolution step 550: f(x)= 75.83103569418248
# differential_evolution step 551: f(x)= 75.83103569418248
# differential_evolution step 552: f(x)= 75.83103569418248
# differential_evolution step 553: f(x)= 75.83103569418248
# differential_evolution step 554: f(x)= 75.83103569418248
# differential_evolution step 555: f(x)= 75.83103569418248
# differential_evolution step 556: f(x)= 75.83101399038276
# differential_evolution step 557: f(x)= 75.83101399038276
# differential_evolution step 558: f(x)= 75.83101399038276
# differential_evolution step 559: f(x)= 75.83101399038276
# differential_evolution step 560: f(x)= 75.83101399038276
# differential_evolution step 561: f(x)= 75.83101399038276
# differential_evolution step 562: f(x)= 75.83101399038276
# differential_evolution step 563: f(x)= 75.83101399038276
# differential_evolution step 564: f(x)= 75.83101399038276
# differential_evolution step 565: f(x)= 75.83101399038276
# differential_evolution step 566: f(x)= 75.83101399038276
# differential_evolution step 567: f(x)= 75.83101399038276
# differential_evolution step 568: f(x)= 75.83101399038276
# differential_evolution step 569: f(x)= 75.83101399038276
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=3.6556, n=1.1054, x_0=39.3472
# Sérsic 2: I_e=4.7447, r_e=5.8232, n=0.3504, x_0=47.6707
# Sérsic 3: I_e=0.2765, r_e=13.5251, n=2.3228, x_0=57.5458
# Chi quadro minimo: 75.83097116154818
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=10.0000, r_e=3.5049, n=1.1478, x_0=39.4539
# Sérsic 2: I_e=3.6978, r_e=5.4843, n=0.5163, x_0=47.6707
# Sérsic 3: I_e=0.3733, r_e=13.0848, n=2.0953, x_0=57.3701
# [1.1055816  0.22385518 0.08534339 0.05614311 1.19619712 2.13092636
#  0.2097913  0.54270212 0.36766796 7.50488496 0.64305765 0.18148077]
# 135.32005243007052

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2272.982945540734
# differential_evolution step 2: f(x)= 2272.982945540734
# differential_evolution step 3: f(x)= 2272.982945540734
# differential_evolution step 4: f(x)= 2272.982945540734
# differential_evolution step 5: f(x)= 834.9828555386102
# differential_evolution step 6: f(x)= 834.9828555386102
# differential_evolution step 7: f(x)= 718.8478207141424
# differential_evolution step 8: f(x)= 361.91950989284913
# differential_evolution step 9: f(x)= 229.18820586374102
# differential_evolution step 10: f(x)= 130.58984279106366
# differential_evolution step 11: f(x)= 130.58984279106366
# differential_evolution step 12: f(x)= 130.58984279106366
# differential_evolution step 13: f(x)= 130.58984279106366
# differential_evolution step 14: f(x)= 130.58984279106366
# differential_evolution step 15: f(x)= 130.58984279106366
# differential_evolution step 16: f(x)= 130.58984279106366
# differential_evolution step 17: f(x)= 130.58984279106366
# differential_evolution step 18: f(x)= 130.58984279106366
# differential_evolution step 19: f(x)= 130.09040255843055
# differential_evolution step 20: f(x)= 130.09040255843055
# differential_evolution step 21: f(x)= 90.81923223751794
# differential_evolution step 22: f(x)= 90.81923223751794
# differential_evolution step 23: f(x)= 52.40222282574066
# differential_evolution step 24: f(x)= 52.40222282574066
# differential_evolution step 25: f(x)= 52.40222282574066
# differential_evolution step 26: f(x)= 52.40222282574066
# differential_evolution step 27: f(x)= 52.40222282574066
# differential_evolution step 28: f(x)= 52.40222282574066
# differential_evolution step 29: f(x)= 52.40222282574066
# differential_evolution step 30: f(x)= 52.40222282574066
# differential_evolution step 31: f(x)= 52.40222282574066
# differential_evolution step 32: f(x)= 52.40222282574066
# differential_evolution step 33: f(x)= 52.40222282574066
# differential_evolution step 34: f(x)= 52.40222282574066
# differential_evolution step 35: f(x)= 47.39880092463133
# differential_evolution step 36: f(x)= 47.39880092463133
# differential_evolution step 37: f(x)= 47.39880092463133
# differential_evolution step 38: f(x)= 47.39880092463133
# differential_evolution step 39: f(x)= 47.39880092463133
# differential_evolution step 40: f(x)= 47.39880092463133
# differential_evolution step 41: f(x)= 47.39880092463133
# differential_evolution step 42: f(x)= 47.39880092463133
# differential_evolution step 43: f(x)= 43.9448431542491
# differential_evolution step 44: f(x)= 43.9448431542491
# differential_evolution step 45: f(x)= 38.08372656185526
# differential_evolution step 46: f(x)= 37.87174299096182
# differential_evolution step 47: f(x)= 37.87174299096182
# differential_evolution step 48: f(x)= 34.30316862372287
# differential_evolution step 49: f(x)= 34.30316862372287
# differential_evolution step 50: f(x)= 31.60164624474763
# differential_evolution step 51: f(x)= 31.60164624474763
# differential_evolution step 52: f(x)= 31.60164624474763
# differential_evolution step 53: f(x)= 31.60164624474763
# differential_evolution step 54: f(x)= 31.60164624474763
# differential_evolution step 55: f(x)= 31.60164624474763
# differential_evolution step 56: f(x)= 31.60164624474763
# differential_evolution step 57: f(x)= 29.25390570904022
# differential_evolution step 58: f(x)= 29.25390570904022
# differential_evolution step 59: f(x)= 29.25390570904022
# differential_evolution step 60: f(x)= 24.087008022744556
# differential_evolution step 61: f(x)= 24.087008022744556
# differential_evolution step 62: f(x)= 24.087008022744556
# differential_evolution step 63: f(x)= 24.087008022744556
# differential_evolution step 64: f(x)= 24.087008022744556
# differential_evolution step 65: f(x)= 24.087008022744556
# differential_evolution step 66: f(x)= 24.087008022744556
# differential_evolution step 67: f(x)= 24.087008022744556
# differential_evolution step 68: f(x)= 24.087008022744556
# differential_evolution step 69: f(x)= 24.087008022744556
# differential_evolution step 70: f(x)= 24.087008022744556
# differential_evolution step 71: f(x)= 23.69137880563528
# differential_evolution step 72: f(x)= 23.69137880563528
# differential_evolution step 73: f(x)= 23.69137880563528
# differential_evolution step 74: f(x)= 22.571450688542242
# differential_evolution step 75: f(x)= 22.571450688542242
# differential_evolution step 76: f(x)= 20.594697866422326
# differential_evolution step 77: f(x)= 20.594697866422326
# differential_evolution step 78: f(x)= 20.594697866422326
# differential_evolution step 79: f(x)= 20.594697866422326
# differential_evolution step 80: f(x)= 20.594697866422326
# differential_evolution step 81: f(x)= 20.594697866422326
# differential_evolution step 82: f(x)= 20.594697866422326
# differential_evolution step 83: f(x)= 20.594697866422326
# differential_evolution step 84: f(x)= 19.333213421562018
# differential_evolution step 85: f(x)= 11.923144422572838
# differential_evolution step 86: f(x)= 11.923144422572838
# differential_evolution step 87: f(x)= 11.923144422572838
# differential_evolution step 88: f(x)= 11.923144422572838
# differential_evolution step 89: f(x)= 11.923144422572838
# differential_evolution step 90: f(x)= 10.109248084227943
# differential_evolution step 91: f(x)= 10.109248084227943
# differential_evolution step 92: f(x)= 10.109248084227943
# differential_evolution step 93: f(x)= 9.93682083308696
# differential_evolution step 94: f(x)= 9.93682083308696
# differential_evolution step 95: f(x)= 8.97946843298557
# differential_evolution step 96: f(x)= 8.97946843298557
# differential_evolution step 97: f(x)= 8.97946843298557
# differential_evolution step 98: f(x)= 8.97946843298557
# differential_evolution step 99: f(x)= 8.97946843298557
# differential_evolution step 100: f(x)= 8.97946843298557
# differential_evolution step 101: f(x)= 6.327185885228913
# differential_evolution step 102: f(x)= 6.327185885228913
# differential_evolution step 103: f(x)= 6.327185885228913
# differential_evolution step 104: f(x)= 6.327185885228913
# differential_evolution step 105: f(x)= 6.327185885228913
# differential_evolution step 106: f(x)= 5.4083709383757075
# differential_evolution step 107: f(x)= 5.4083709383757075
# differential_evolution step 108: f(x)= 5.4083709383757075
# differential_evolution step 109: f(x)= 5.4083709383757075
# differential_evolution step 110: f(x)= 5.4083709383757075
# differential_evolution step 111: f(x)= 5.4083709383757075
# differential_evolution step 112: f(x)= 5.4083709383757075
# differential_evolution step 113: f(x)= 5.4083709383757075
# differential_evolution step 114: f(x)= 5.093184161151387
# differential_evolution step 115: f(x)= 5.093184161151387
# differential_evolution step 116: f(x)= 5.093184161151387
# differential_evolution step 117: f(x)= 5.093184161151387
# differential_evolution step 118: f(x)= 5.093184161151387
# differential_evolution step 119: f(x)= 5.093184161151387
# differential_evolution step 120: f(x)= 5.093184161151387
# differential_evolution step 121: f(x)= 4.01306252370152
# differential_evolution step 122: f(x)= 4.01306252370152
# differential_evolution step 123: f(x)= 4.01306252370152
# differential_evolution step 124: f(x)= 4.01306252370152
# differential_evolution step 125: f(x)= 4.01306252370152
# differential_evolution step 126: f(x)= 4.01306252370152
# differential_evolution step 127: f(x)= 4.01306252370152
# differential_evolution step 128: f(x)= 4.01306252370152
# differential_evolution step 129: f(x)= 4.01306252370152
# differential_evolution step 130: f(x)= 4.01306252370152
# differential_evolution step 131: f(x)= 4.01306252370152
# differential_evolution step 132: f(x)= 4.01306252370152
# differential_evolution step 133: f(x)= 3.7537300718864164
# differential_evolution step 134: f(x)= 3.7537300718864164
# differential_evolution step 135: f(x)= 3.7537300718864164
# differential_evolution step 136: f(x)= 3.7537300718864164
# differential_evolution step 137: f(x)= 3.7537300718864164
# differential_evolution step 138: f(x)= 3.7537300718864164
# differential_evolution step 139: f(x)= 3.7537300718864164
# differential_evolution step 140: f(x)= 3.7537300718864164
# differential_evolution step 141: f(x)= 3.7537300718864164
# differential_evolution step 142: f(x)= 3.7537300718864164
# differential_evolution step 143: f(x)= 3.7537300718864164
# differential_evolution step 144: f(x)= 3.7537300718864164
# differential_evolution step 145: f(x)= 3.7537300718864164
# differential_evolution step 146: f(x)= 3.7537300718864164
# differential_evolution step 147: f(x)= 3.6084678725842765
# differential_evolution step 148: f(x)= 3.6084678725842765
# differential_evolution step 149: f(x)= 3.6084678725842765
# differential_evolution step 150: f(x)= 3.6084678725842765
# differential_evolution step 151: f(x)= 3.6084678725842765
# differential_evolution step 152: f(x)= 3.6084678725842765
# differential_evolution step 153: f(x)= 3.6084678725842765
# differential_evolution step 154: f(x)= 3.6084678725842765
# differential_evolution step 155: f(x)= 3.580890151983233
# differential_evolution step 156: f(x)= 3.580890151983233
# differential_evolution step 157: f(x)= 3.580890151983233
# differential_evolution step 158: f(x)= 3.580890151983233
# differential_evolution step 159: f(x)= 3.580890151983233
# differential_evolution step 160: f(x)= 3.57419473126938
# differential_evolution step 161: f(x)= 3.5426075179620176
# differential_evolution step 162: f(x)= 3.5339029879586312
# differential_evolution step 163: f(x)= 3.4439582675983798
# differential_evolution step 164: f(x)= 3.4439582675983798
# differential_evolution step 165: f(x)= 3.4439582675983798
# differential_evolution step 166: f(x)= 3.4439582675983798
# differential_evolution step 167: f(x)= 3.4060922774882814
# differential_evolution step 168: f(x)= 3.4060922774882814
# differential_evolution step 169: f(x)= 3.4060922774882814
# differential_evolution step 170: f(x)= 3.4060922774882814
# differential_evolution step 171: f(x)= 3.4060922774882814
# differential_evolution step 172: f(x)= 3.4060922774882814
# differential_evolution step 173: f(x)= 3.4060922774882814
# differential_evolution step 174: f(x)= 3.310596686596226
# differential_evolution step 175: f(x)= 3.310596686596226
# differential_evolution step 176: f(x)= 3.310596686596226
# differential_evolution step 177: f(x)= 3.310596686596226
# differential_evolution step 178: f(x)= 3.240013683058461
# differential_evolution step 179: f(x)= 3.240013683058461
# differential_evolution step 180: f(x)= 3.214593333571158
# differential_evolution step 181: f(x)= 3.153125595548012
# differential_evolution step 182: f(x)= 3.153125595548012
# differential_evolution step 183: f(x)= 3.153125595548012
# differential_evolution step 184: f(x)= 3.153125595548012
# differential_evolution step 185: f(x)= 3.153125595548012
# differential_evolution step 186: f(x)= 3.153125595548012
# differential_evolution step 187: f(x)= 3.153125595548012
# differential_evolution step 188: f(x)= 3.153125595548012
# differential_evolution step 189: f(x)= 3.153125595548012
# differential_evolution step 190: f(x)= 3.153125595548012
# differential_evolution step 191: f(x)= 3.153125595548012
# differential_evolution step 192: f(x)= 3.140794709526532
# differential_evolution step 193: f(x)= 3.140794709526532
# differential_evolution step 194: f(x)= 3.140794709526532
# differential_evolution step 195: f(x)= 3.140794709526532
# differential_evolution step 196: f(x)= 3.1162349831288996
# differential_evolution step 197: f(x)= 3.1162349831288996
# differential_evolution step 198: f(x)= 3.1162349831288996
# differential_evolution step 199: f(x)= 3.1162349831288996
# differential_evolution step 200: f(x)= 3.1162349831288996
# differential_evolution step 201: f(x)= 3.1162349831288996
# differential_evolution step 202: f(x)= 3.1162349831288996
# differential_evolution step 203: f(x)= 3.1162349831288996
# differential_evolution step 204: f(x)= 3.1162349831288996
# differential_evolution step 205: f(x)= 3.1162349831288996
# differential_evolution step 206: f(x)= 3.1162349831288996
# differential_evolution step 207: f(x)= 3.1162349831288996
# differential_evolution step 208: f(x)= 3.1162349831288996
# differential_evolution step 209: f(x)= 3.1130871811695338
# differential_evolution step 210: f(x)= 3.1130871811695338
# differential_evolution step 211: f(x)= 3.0803717708513005
# differential_evolution step 212: f(x)= 3.0803717708513005
# differential_evolution step 213: f(x)= 3.066262092667028
# differential_evolution step 214: f(x)= 3.066262092667028
# differential_evolution step 215: f(x)= 3.066262092667028
# differential_evolution step 216: f(x)= 3.066262092667028
# differential_evolution step 217: f(x)= 3.066262092667028
# differential_evolution step 218: f(x)= 3.066262092667028
# differential_evolution step 219: f(x)= 3.066262092667028
# differential_evolution step 220: f(x)= 3.066262092667028
# differential_evolution step 221: f(x)= 3.0575616505388323
# differential_evolution step 222: f(x)= 3.0575616505388323
# differential_evolution step 223: f(x)= 3.0575616505388323
# differential_evolution step 224: f(x)= 3.035594702640439
# differential_evolution step 225: f(x)= 3.035594702640439
# differential_evolution step 226: f(x)= 3.0284757610601556
# differential_evolution step 227: f(x)= 3.0284757610601556
# differential_evolution step 228: f(x)= 3.0284757610601556
# differential_evolution step 229: f(x)= 3.0284757610601556
# differential_evolution step 230: f(x)= 2.990911575611799
# differential_evolution step 231: f(x)= 2.990911575611799
# differential_evolution step 232: f(x)= 2.990911575611799
# differential_evolution step 233: f(x)= 2.990911575611799
# differential_evolution step 234: f(x)= 2.990911575611799
# differential_evolution step 235: f(x)= 2.9666291196901806
# differential_evolution step 236: f(x)= 2.9666291196901806
# differential_evolution step 237: f(x)= 2.958347216604435
# differential_evolution step 238: f(x)= 2.9379710549775315
# differential_evolution step 239: f(x)= 2.9379710549775315
# differential_evolution step 240: f(x)= 2.9379710549775315
# differential_evolution step 241: f(x)= 2.9261022868636903
# differential_evolution step 242: f(x)= 2.9261022868636903
# differential_evolution step 243: f(x)= 2.9261022868636903
# differential_evolution step 244: f(x)= 2.9261022868636903
# differential_evolution step 245: f(x)= 2.9261022868636903
# differential_evolution step 246: f(x)= 2.8982795615593355
# differential_evolution step 247: f(x)= 2.8982795615593355
# differential_evolution step 248: f(x)= 2.877121904081441
# differential_evolution step 249: f(x)= 2.877121904081441
# differential_evolution step 250: f(x)= 2.877121904081441
# differential_evolution step 251: f(x)= 2.877121904081441
# differential_evolution step 252: f(x)= 2.877121904081441
# differential_evolution step 253: f(x)= 2.877121904081441
# differential_evolution step 254: f(x)= 2.876933522702713
# differential_evolution step 255: f(x)= 2.8711200552744844
# differential_evolution step 256: f(x)= 2.8711200552744844
# differential_evolution step 257: f(x)= 2.8456008256006937
# differential_evolution step 258: f(x)= 2.8456008256006937
# differential_evolution step 259: f(x)= 2.8456008256006937
# differential_evolution step 260: f(x)= 2.8456008256006937
# differential_evolution step 261: f(x)= 2.828591916218643
# differential_evolution step 262: f(x)= 2.828591916218643
# differential_evolution step 263: f(x)= 2.828591916218643
# differential_evolution step 264: f(x)= 2.828591916218643
# differential_evolution step 265: f(x)= 2.828591916218643
# differential_evolution step 266: f(x)= 2.7734089509206723
# differential_evolution step 267: f(x)= 2.7734089509206723
# differential_evolution step 268: f(x)= 2.7734089509206723
# differential_evolution step 269: f(x)= 2.7734089509206723
# differential_evolution step 270: f(x)= 2.7734089509206723
# differential_evolution step 271: f(x)= 2.7734089509206723
# differential_evolution step 272: f(x)= 2.7734089509206723
# differential_evolution step 273: f(x)= 2.7734089509206723
# differential_evolution step 274: f(x)= 2.7734089509206723
# differential_evolution step 275: f(x)= 2.7734089509206723
# differential_evolution step 276: f(x)= 2.7734089509206723
# differential_evolution step 277: f(x)= 2.7381835148052613
# differential_evolution step 278: f(x)= 2.7232613939228543
# differential_evolution step 279: f(x)= 2.7232613939228543
# differential_evolution step 280: f(x)= 2.7232613939228543
# differential_evolution step 281: f(x)= 2.7232613939228543
# differential_evolution step 282: f(x)= 2.7232613939228543
# differential_evolution step 283: f(x)= 2.7232613939228543
# differential_evolution step 284: f(x)= 2.7232613939228543
# differential_evolution step 285: f(x)= 2.7232613939228543
# differential_evolution step 286: f(x)= 2.7232613939228543
# differential_evolution step 287: f(x)= 2.6941692001114386
# differential_evolution step 288: f(x)= 2.6677104768837854
# differential_evolution step 289: f(x)= 2.6596088707302585
# differential_evolution step 290: f(x)= 2.6403858173625108
# differential_evolution step 291: f(x)= 2.6403858173625108
# differential_evolution step 292: f(x)= 2.6403858173625108
# differential_evolution step 293: f(x)= 2.6403858173625108
# differential_evolution step 294: f(x)= 2.6403858173625108
# differential_evolution step 295: f(x)= 2.608357149239507
# differential_evolution step 296: f(x)= 2.608357149239507
# differential_evolution step 297: f(x)= 2.6056532551227125
# differential_evolution step 298: f(x)= 2.6056532551227125
# differential_evolution step 299: f(x)= 2.6056532551227125
# differential_evolution step 300: f(x)= 2.6056532551227125
# differential_evolution step 301: f(x)= 2.6056532551227125
# differential_evolution step 302: f(x)= 2.6056532551227125
# differential_evolution step 303: f(x)= 2.5510367104753584
# differential_evolution step 304: f(x)= 2.5510367104753584
# differential_evolution step 305: f(x)= 2.5332681403041337
# differential_evolution step 306: f(x)= 2.5332681403041337
# differential_evolution step 307: f(x)= 2.5332681403041337
# differential_evolution step 308: f(x)= 2.5332681403041337
# differential_evolution step 309: f(x)= 2.5332681403041337
# differential_evolution step 310: f(x)= 2.53079965206735
# differential_evolution step 311: f(x)= 2.53079965206735
# differential_evolution step 312: f(x)= 2.53079965206735
# differential_evolution step 313: f(x)= 2.53079965206735
# differential_evolution step 314: f(x)= 2.53079965206735
# differential_evolution step 315: f(x)= 2.53079965206735
# differential_evolution step 316: f(x)= 2.4968201981520974
# differential_evolution step 317: f(x)= 2.4968201981520974
# differential_evolution step 318: f(x)= 2.4968201981520974
# differential_evolution step 319: f(x)= 2.4968201981520974
# differential_evolution step 320: f(x)= 2.481450211960723
# differential_evolution step 321: f(x)= 2.481450211960723
# differential_evolution step 322: f(x)= 2.481450211960723
# differential_evolution step 323: f(x)= 2.481450211960723
# differential_evolution step 324: f(x)= 2.481450211960723
# differential_evolution step 325: f(x)= 2.481450211960723
# differential_evolution step 326: f(x)= 2.481450211960723
# differential_evolution step 327: f(x)= 2.4763017695603224
# differential_evolution step 328: f(x)= 2.4763017695603224
# differential_evolution step 329: f(x)= 2.4763017695603224
# differential_evolution step 330: f(x)= 2.4763017695603224
# differential_evolution step 331: f(x)= 2.4763017695603224
# differential_evolution step 332: f(x)= 2.459692803667847
# differential_evolution step 333: f(x)= 2.459692803667847
# differential_evolution step 334: f(x)= 2.4427862595520375
# differential_evolution step 335: f(x)= 2.4427862595520375
# differential_evolution step 336: f(x)= 2.4427862595520375
# differential_evolution step 337: f(x)= 2.420088722439947
# differential_evolution step 338: f(x)= 2.4117716246297083
# differential_evolution step 339: f(x)= 2.4117716246297083
# differential_evolution step 340: f(x)= 2.4117716246297083
# differential_evolution step 341: f(x)= 2.4117716246297083
# differential_evolution step 342: f(x)= 2.4117716246297083
# differential_evolution step 343: f(x)= 2.4117716246297083
# differential_evolution step 344: f(x)= 2.397488854787529
# differential_evolution step 345: f(x)= 2.397488854787529
# differential_evolution step 346: f(x)= 2.397488854787529
# differential_evolution step 347: f(x)= 2.397488854787529
# differential_evolution step 348: f(x)= 2.397488854787529
# differential_evolution step 349: f(x)= 2.397488854787529
# differential_evolution step 350: f(x)= 2.385898378410589
# differential_evolution step 351: f(x)= 2.385898378410589
# differential_evolution step 352: f(x)= 2.385898378410589
# differential_evolution step 353: f(x)= 2.385898378410589
# differential_evolution step 354: f(x)= 2.384022574264017
# differential_evolution step 355: f(x)= 2.384022574264017
# differential_evolution step 356: f(x)= 2.3803850360223855
# differential_evolution step 357: f(x)= 2.3803850360223855
# differential_evolution step 358: f(x)= 2.3803850360223855
# differential_evolution step 359: f(x)= 2.3803850360223855
# differential_evolution step 360: f(x)= 2.3803850360223855
# differential_evolution step 361: f(x)= 2.3803850360223855
# differential_evolution step 362: f(x)= 2.3803850360223855
# differential_evolution step 363: f(x)= 2.3803850360223855
# differential_evolution step 364: f(x)= 2.3803850360223855
# differential_evolution step 365: f(x)= 2.3803850360223855
# differential_evolution step 366: f(x)= 2.3803850360223855
# differential_evolution step 367: f(x)= 2.368645879661794
# differential_evolution step 368: f(x)= 2.368645879661794
# differential_evolution step 369: f(x)= 2.3640280014090163
# differential_evolution step 370: f(x)= 2.3640280014090163
# differential_evolution step 371: f(x)= 2.363203402453968
# differential_evolution step 372: f(x)= 2.363203402453968
# differential_evolution step 373: f(x)= 2.363203402453968
# differential_evolution step 374: f(x)= 2.3581599414450896
# differential_evolution step 375: f(x)= 2.3581599414450896
# differential_evolution step 376: f(x)= 2.3581599414450896
# differential_evolution step 377: f(x)= 2.3581599414450896
# differential_evolution step 378: f(x)= 2.3581599414450896
# differential_evolution step 379: f(x)= 2.3581599414450896
# differential_evolution step 380: f(x)= 2.3581599414450896
# differential_evolution step 381: f(x)= 2.3581599414450896
# differential_evolution step 382: f(x)= 2.3581599414450896
# differential_evolution step 383: f(x)= 2.3581599414450896
# differential_evolution step 384: f(x)= 2.3581599414450896
# differential_evolution step 385: f(x)= 2.3581599414450896
# differential_evolution step 386: f(x)= 2.3581599414450896
# differential_evolution step 387: f(x)= 2.3581599414450896
# differential_evolution step 388: f(x)= 2.3549756762415197
# differential_evolution step 389: f(x)= 2.3549756762415197
# differential_evolution step 390: f(x)= 2.3538395013160494
# differential_evolution step 391: f(x)= 2.3518626342018667
# differential_evolution step 392: f(x)= 2.3518626342018667
# differential_evolution step 393: f(x)= 2.3518626342018667
# differential_evolution step 394: f(x)= 2.3518626342018667
# differential_evolution step 395: f(x)= 2.350874282867476
# differential_evolution step 396: f(x)= 2.3465564991227845
# differential_evolution step 397: f(x)= 2.3465564991227845
# differential_evolution step 398: f(x)= 2.3465564991227845
# differential_evolution step 399: f(x)= 2.3465564991227845
# differential_evolution step 400: f(x)= 2.3465564991227845
# differential_evolution step 401: f(x)= 2.3465564991227845
# differential_evolution step 402: f(x)= 2.3465564991227845
# differential_evolution step 403: f(x)= 2.3465564991227845
# differential_evolution step 404: f(x)= 2.3465564991227845
# differential_evolution step 405: f(x)= 2.3465564991227845
# differential_evolution step 406: f(x)= 2.3465564991227845
# differential_evolution step 407: f(x)= 2.3454163259252447
# differential_evolution step 408: f(x)= 2.3454163259252447
# differential_evolution step 409: f(x)= 2.3454163259252447
# differential_evolution step 410: f(x)= 2.3454163259252447
# differential_evolution step 411: f(x)= 2.3454163259252447
# differential_evolution step 412: f(x)= 2.3454163259252447
# differential_evolution step 413: f(x)= 2.3454163259252447
# differential_evolution step 414: f(x)= 2.3430794858175306
# differential_evolution step 415: f(x)= 2.3430794858175306
# differential_evolution step 416: f(x)= 2.342708451027707
# differential_evolution step 417: f(x)= 2.342708451027707
# differential_evolution step 418: f(x)= 2.342708451027707
# differential_evolution step 419: f(x)= 2.342708451027707
# differential_evolution step 420: f(x)= 2.342708451027707
# differential_evolution step 421: f(x)= 2.342708451027707
# differential_evolution step 422: f(x)= 2.342708451027707
# differential_evolution step 423: f(x)= 2.342708451027707
# differential_evolution step 424: f(x)= 2.3414844189795003
# differential_evolution step 425: f(x)= 2.3414844189795003
# differential_evolution step 426: f(x)= 2.3408569702580313
# differential_evolution step 427: f(x)= 2.3408569702580313
# differential_evolution step 428: f(x)= 2.3408569702580313
# differential_evolution step 429: f(x)= 2.3408569702580313
# differential_evolution step 430: f(x)= 2.3406360004109534
# differential_evolution step 431: f(x)= 2.3406360004109534
# differential_evolution step 432: f(x)= 2.3406360004109534
# differential_evolution step 433: f(x)= 2.3406360004109534
# differential_evolution step 434: f(x)= 2.3406360004109534
# differential_evolution step 435: f(x)= 2.3406360004109534
# differential_evolution step 436: f(x)= 2.3406360004109534
# differential_evolution step 437: f(x)= 2.3406360004109534
# differential_evolution step 438: f(x)= 2.3406360004109534
# differential_evolution step 439: f(x)= 2.3406360004109534
# differential_evolution step 440: f(x)= 2.3395409608665574
# differential_evolution step 441: f(x)= 2.3393611611694456
# differential_evolution step 442: f(x)= 2.3393611611694456
# differential_evolution step 443: f(x)= 2.3393611611694456
# differential_evolution step 444: f(x)= 2.3393611611694456
# differential_evolution step 445: f(x)= 2.3393254198208866
# differential_evolution step 446: f(x)= 2.3393254198208866
# differential_evolution step 447: f(x)= 2.3393254198208866
# differential_evolution step 448: f(x)= 2.3393254198208866
# differential_evolution step 449: f(x)= 2.3393254198208866
# differential_evolution step 450: f(x)= 2.338482519826292
# differential_evolution step 451: f(x)= 2.338482519826292
# differential_evolution step 452: f(x)= 2.338482519826292
# differential_evolution step 453: f(x)= 2.338482519826292
# differential_evolution step 454: f(x)= 2.338482519826292
# differential_evolution step 455: f(x)= 2.338482519826292
# differential_evolution step 456: f(x)= 2.338482519826292
# differential_evolution step 457: f(x)= 2.338482519826292
# differential_evolution step 458: f(x)= 2.338482519826292
# differential_evolution step 459: f(x)= 2.3378943598446185
# differential_evolution step 460: f(x)= 2.3378943598446185
# differential_evolution step 461: f(x)= 2.3378943598446185
# differential_evolution step 462: f(x)= 2.3378943598446185
# differential_evolution step 463: f(x)= 2.3378943598446185
# differential_evolution step 464: f(x)= 2.3378943598446185
# differential_evolution step 465: f(x)= 2.3378943598446185
# differential_evolution step 466: f(x)= 2.3378943598446185
# differential_evolution step 467: f(x)= 2.3378943598446185
# differential_evolution step 468: f(x)= 2.3378943598446185
# differential_evolution step 469: f(x)= 2.3378943598446185
# differential_evolution step 470: f(x)= 2.3378943598446185
# differential_evolution step 471: f(x)= 2.3378943598446185
# differential_evolution step 472: f(x)= 2.3378943598446185
# differential_evolution step 473: f(x)= 2.3378943598446185
# differential_evolution step 474: f(x)= 2.3378943598446185
# differential_evolution step 475: f(x)= 2.3378943598446185
# differential_evolution step 476: f(x)= 2.3378943598446185
# differential_evolution step 477: f(x)= 2.3378943598446185
# differential_evolution step 478: f(x)= 2.3378943598446185
# differential_evolution step 479: f(x)= 2.3378943598446185
# differential_evolution step 480: f(x)= 2.3378558773523084
# differential_evolution step 481: f(x)= 2.3378558773523084
# differential_evolution step 482: f(x)= 2.3378483577432156
# differential_evolution step 483: f(x)= 2.3378483577432156
# differential_evolution step 484: f(x)= 2.3378483577432156
# differential_evolution step 485: f(x)= 2.3378483577432156
# differential_evolution step 486: f(x)= 2.3378483577432156
# differential_evolution step 487: f(x)= 2.3378483577432156
# differential_evolution step 488: f(x)= 2.3378483577432156
# differential_evolution step 489: f(x)= 2.3378483577432156
# differential_evolution step 490: f(x)= 2.3378483577432156
# differential_evolution step 491: f(x)= 2.3378483577432156
# differential_evolution step 492: f(x)= 2.3378483577432156
# differential_evolution step 493: f(x)= 2.3378483577432156
# differential_evolution step 494: f(x)= 2.3378483577432156
# differential_evolution step 495: f(x)= 2.3378483577432156
# differential_evolution step 496: f(x)= 2.3378483577432156
# differential_evolution step 497: f(x)= 2.3378483577432156
# differential_evolution step 498: f(x)= 2.3378483577432156
# differential_evolution step 499: f(x)= 2.3378483577432156
# differential_evolution step 500: f(x)= 2.3378483577432156
# differential_evolution step 501: f(x)= 2.3378483577432156
# differential_evolution step 502: f(x)= 2.3378483577432156
# differential_evolution step 503: f(x)= 2.3378483577432156
# differential_evolution step 504: f(x)= 2.3378483577432156
# differential_evolution step 505: f(x)= 2.3378062669795994
# differential_evolution step 506: f(x)= 2.3378062669795994
# differential_evolution step 507: f(x)= 2.3378062669795994
# differential_evolution step 508: f(x)= 2.3378062669795994
# differential_evolution step 509: f(x)= 2.3378062669795994
# differential_evolution step 510: f(x)= 2.3372523390480016
# differential_evolution step 511: f(x)= 2.3372523390480016
# differential_evolution step 512: f(x)= 2.3372523390480016
# differential_evolution step 513: f(x)= 2.3372523390480016
# differential_evolution step 514: f(x)= 2.3372523390480016
# differential_evolution step 515: f(x)= 2.3372523390480016
# differential_evolution step 516: f(x)= 2.3372523390480016
# differential_evolution step 517: f(x)= 2.3372523390480016
# differential_evolution step 518: f(x)= 2.3372523390480016
# differential_evolution step 519: f(x)= 2.3372523390480016
# differential_evolution step 520: f(x)= 2.3372523390480016
# differential_evolution step 521: f(x)= 2.3372523390480016
# differential_evolution step 522: f(x)= 2.3372523390480016
# differential_evolution step 523: f(x)= 2.3372523390480016
# differential_evolution step 524: f(x)= 2.3372523390480016
# differential_evolution step 525: f(x)= 2.3372523390480016
# differential_evolution step 526: f(x)= 2.3372523390480016
# differential_evolution step 527: f(x)= 2.3372523390480016
# differential_evolution step 528: f(x)= 2.3372523390480016
# differential_evolution step 529: f(x)= 2.3372523390480016
# differential_evolution step 530: f(x)= 2.3372523390480016
# differential_evolution step 531: f(x)= 2.3372523390480016
# differential_evolution step 532: f(x)= 2.3372523390480016
# differential_evolution step 533: f(x)= 2.3372523390480016
# differential_evolution step 534: f(x)= 2.3372523390480016
# differential_evolution step 535: f(x)= 2.3372523390480016
# differential_evolution step 536: f(x)= 2.3371825949934704
# differential_evolution step 537: f(x)= 2.3371825949934704
# differential_evolution step 538: f(x)= 2.3371825949934704
# differential_evolution step 539: f(x)= 2.3371825949934704
# differential_evolution step 540: f(x)= 2.3371719154359143
# differential_evolution step 541: f(x)= 2.3371719154359143
# differential_evolution step 542: f(x)= 2.3371719154359143
# differential_evolution step 543: f(x)= 2.3371607285695473
# differential_evolution step 544: f(x)= 2.3371607285695473
# differential_evolution step 545: f(x)= 2.3371607285695473
# differential_evolution step 546: f(x)= 2.3371341016606317
# differential_evolution step 547: f(x)= 2.3371341016606317
# differential_evolution step 548: f(x)= 2.33709862180843
# differential_evolution step 549: f(x)= 2.33709862180843
# differential_evolution step 550: f(x)= 2.33709862180843
# differential_evolution step 551: f(x)= 2.33709862180843
# differential_evolution step 552: f(x)= 2.33709862180843
# differential_evolution step 553: f(x)= 2.336987409653865
# differential_evolution step 554: f(x)= 2.336987409653865
# differential_evolution step 555: f(x)= 2.336987409653865
# differential_evolution step 556: f(x)= 2.336987409653865
# differential_evolution step 557: f(x)= 2.336987409653865
# differential_evolution step 558: f(x)= 2.336987409653865
# differential_evolution step 559: f(x)= 2.336987409653865
# differential_evolution step 560: f(x)= 2.336987409653865
# differential_evolution step 561: f(x)= 2.336987409653865
# differential_evolution step 562: f(x)= 2.3369843231606584
# differential_evolution step 563: f(x)= 2.3369176860742815
# differential_evolution step 564: f(x)= 2.3369176860742815
# differential_evolution step 565: f(x)= 2.3369176860742815
# differential_evolution step 566: f(x)= 2.3369176860742815
# differential_evolution step 567: f(x)= 2.336877109845797
# differential_evolution step 568: f(x)= 2.336877109845797
# differential_evolution step 569: f(x)= 2.3368295855630743
# differential_evolution step 570: f(x)= 2.3368295855630743
# differential_evolution step 571: f(x)= 2.3368295855630743
# differential_evolution step 572: f(x)= 2.3368295855630743
# differential_evolution step 573: f(x)= 2.3368295855630743
# differential_evolution step 574: f(x)= 2.3368295855630743
# differential_evolution step 575: f(x)= 2.3368295855630743
# differential_evolution step 576: f(x)= 2.3368295855630743
# differential_evolution step 577: f(x)= 2.3368295855630743
# differential_evolution step 578: f(x)= 2.3368295855630743
# differential_evolution step 579: f(x)= 2.336813408774667
# differential_evolution step 580: f(x)= 2.336813408774667
# differential_evolution step 581: f(x)= 2.336813408774667
# differential_evolution step 582: f(x)= 2.336813408774667
# differential_evolution step 583: f(x)= 2.336813408774667
# differential_evolution step 584: f(x)= 2.336813408774667
# differential_evolution step 585: f(x)= 2.336813408774667
# differential_evolution step 586: f(x)= 2.336813408774667
# differential_evolution step 587: f(x)= 2.336813408774667
# differential_evolution step 588: f(x)= 2.336813408774667
# differential_evolution step 589: f(x)= 2.336813408774667
# differential_evolution step 590: f(x)= 2.336813408774667
# differential_evolution step 591: f(x)= 2.336813408774667
# differential_evolution step 592: f(x)= 2.336813408774667
# differential_evolution step 593: f(x)= 2.336813408774667
# differential_evolution step 594: f(x)= 2.336813408774667
# differential_evolution step 595: f(x)= 2.336813408774667
# differential_evolution step 596: f(x)= 2.336813408774667
# differential_evolution step 597: f(x)= 2.336813408774667
# differential_evolution step 598: f(x)= 2.336813408774667
# differential_evolution step 599: f(x)= 2.336801823609597
# differential_evolution step 600: f(x)= 2.336801823609597
# differential_evolution step 601: f(x)= 2.336801823609597
# differential_evolution step 602: f(x)= 2.336793261996354
# differential_evolution step 603: f(x)= 2.336785086727717
# differential_evolution step 604: f(x)= 2.336785086727717
# differential_evolution step 605: f(x)= 2.336785086727717
# differential_evolution step 606: f(x)= 2.336785086727717
# differential_evolution step 607: f(x)= 2.336785086727717
# differential_evolution step 608: f(x)= 2.336785086727717
# differential_evolution step 609: f(x)= 2.336785086727717
# differential_evolution step 610: f(x)= 2.336785086727717
# differential_evolution step 611: f(x)= 2.336785086727717
# differential_evolution step 612: f(x)= 2.336785086727717
# differential_evolution step 613: f(x)= 2.336785086727717
# differential_evolution step 614: f(x)= 2.336785086727717
# differential_evolution step 615: f(x)= 2.33677388949051
# differential_evolution step 616: f(x)= 2.33677388949051
# differential_evolution step 617: f(x)= 2.33677388949051
# differential_evolution step 618: f(x)= 2.33677388949051
# differential_evolution step 619: f(x)= 2.33677388949051
# differential_evolution step 620: f(x)= 2.33677388949051
# differential_evolution step 621: f(x)= 2.33677388949051
# differential_evolution step 622: f(x)= 2.33677388949051
# differential_evolution step 623: f(x)= 2.33677388949051
# differential_evolution step 624: f(x)= 2.33677388949051
# differential_evolution step 625: f(x)= 2.33677388949051
# differential_evolution step 626: f(x)= 2.33677388949051
# differential_evolution step 627: f(x)= 2.33677388949051
# differential_evolution step 628: f(x)= 2.336753439508563
# differential_evolution step 629: f(x)= 2.336753439508563
# differential_evolution step 630: f(x)= 2.336753439508563
# differential_evolution step 631: f(x)= 2.336753439508563
# differential_evolution step 632: f(x)= 2.336753439508563
# differential_evolution step 633: f(x)= 2.336753439508563
# differential_evolution step 634: f(x)= 2.336753439508563
# differential_evolution step 635: f(x)= 2.336753439508563
# differential_evolution step 636: f(x)= 2.336753439508563
# differential_evolution step 637: f(x)= 2.336751978509313
# differential_evolution step 638: f(x)= 2.336751978509313
# differential_evolution step 639: f(x)= 2.336751978509313
# differential_evolution step 640: f(x)= 2.336751978509313
# differential_evolution step 641: f(x)= 2.336751978509313
# differential_evolution step 642: f(x)= 2.3367478260332617
# differential_evolution step 643: f(x)= 2.3367478260332617
# differential_evolution step 644: f(x)= 2.336741446569375
# differential_evolution step 645: f(x)= 2.336741446569375
# differential_evolution step 646: f(x)= 2.336741446569375
# differential_evolution step 647: f(x)= 2.336741446569375
# differential_evolution step 648: f(x)= 2.3367388452791897
# differential_evolution step 649: f(x)= 2.3367388452791897
# differential_evolution step 650: f(x)= 2.3367388452791897
# differential_evolution step 651: f(x)= 2.3367388452791897
# differential_evolution step 652: f(x)= 2.3367388452791897
# differential_evolution step 653: f(x)= 2.336736216436179
# differential_evolution step 654: f(x)= 2.336736216436179
# differential_evolution step 655: f(x)= 2.336736216436179
# differential_evolution step 656: f(x)= 2.3367354860216034
# differential_evolution step 657: f(x)= 2.3367354860216034
# differential_evolution step 658: f(x)= 2.3367354860216034
# differential_evolution step 659: f(x)= 2.3367354860216034
# differential_evolution step 660: f(x)= 2.3367295997969433
# differential_evolution step 661: f(x)= 2.3367295997969433
# differential_evolution step 662: f(x)= 2.3367295997969433
# differential_evolution step 663: f(x)= 2.336728820872902
# differential_evolution step 664: f(x)= 2.336728820872902
# differential_evolution step 665: f(x)= 2.336728820872902
# differential_evolution step 666: f(x)= 2.336728820872902
# differential_evolution step 667: f(x)= 2.336728820872902
# differential_evolution step 668: f(x)= 2.336728820872902
# differential_evolution step 669: f(x)= 2.336728820872902
# differential_evolution step 670: f(x)= 2.336728820872902
# differential_evolution step 671: f(x)= 2.336728820872902
# differential_evolution step 672: f(x)= 2.336728820872902
# differential_evolution step 673: f(x)= 2.336728820872902
# differential_evolution step 674: f(x)= 2.336728820872902
# differential_evolution step 675: f(x)= 2.336728820872902
# differential_evolution step 676: f(x)= 2.336728820872902
# differential_evolution step 677: f(x)= 2.336728820872902
# differential_evolution step 678: f(x)= 2.336728820872902
# differential_evolution step 679: f(x)= 2.336728515716259
# differential_evolution step 680: f(x)= 2.336728515716259
# differential_evolution step 681: f(x)= 2.336728515716259
# differential_evolution step 682: f(x)= 2.336728515716259
# differential_evolution step 683: f(x)= 2.336728251815857
# differential_evolution step 684: f(x)= 2.336728251815857
# differential_evolution step 685: f(x)= 2.336728251815857
# differential_evolution step 686: f(x)= 2.336728251815857
# differential_evolution step 687: f(x)= 2.336728251815857
# differential_evolution step 688: f(x)= 2.3367256069801923
# differential_evolution step 689: f(x)= 2.336724115034432
# differential_evolution step 690: f(x)= 2.336724115034432
# differential_evolution step 691: f(x)= 2.336724115034432
# differential_evolution step 692: f(x)= 2.336724115034432
# differential_evolution step 693: f(x)= 2.336724115034432
# differential_evolution step 694: f(x)= 2.336724115034432
# differential_evolution step 695: f(x)= 2.336724115034432
# differential_evolution step 696: f(x)= 2.336724115034432
# differential_evolution step 697: f(x)= 2.336724115034432
# differential_evolution step 698: f(x)= 2.3367240734579893
# differential_evolution step 699: f(x)= 2.3367240734579893
# differential_evolution step 700: f(x)= 2.3367240734579893
# differential_evolution step 701: f(x)= 2.3367240734579893
# differential_evolution step 702: f(x)= 2.3367240734579893
# differential_evolution step 703: f(x)= 2.3367240734579893
# differential_evolution step 704: f(x)= 2.3367240734579893
# differential_evolution step 705: f(x)= 2.3367240734579893
# differential_evolution step 706: f(x)= 2.336724055469757
# differential_evolution step 707: f(x)= 2.3367240360544077
# differential_evolution step 708: f(x)= 2.3367240360544077
# differential_evolution step 709: f(x)= 2.3367240360544077
# differential_evolution step 710: f(x)= 2.3367240360544077
# differential_evolution step 711: f(x)= 2.3367240360544077
# differential_evolution step 712: f(x)= 2.336722554291301
# differential_evolution step 713: f(x)= 2.336722554291301
# differential_evolution step 714: f(x)= 2.336722554291301
# differential_evolution step 715: f(x)= 2.336722554291301
# differential_evolution step 716: f(x)= 2.336722554291301
# differential_evolution step 717: f(x)= 2.336722554291301
# differential_evolution step 718: f(x)= 2.336722554291301
# differential_evolution step 719: f(x)= 2.336722554291301
# differential_evolution step 720: f(x)= 2.336722554291301
# differential_evolution step 721: f(x)= 2.336721927603217
# differential_evolution step 722: f(x)= 2.336721927603217
# differential_evolution step 723: f(x)= 2.336721927603217
# differential_evolution step 724: f(x)= 2.336721927603217
# differential_evolution step 725: f(x)= 2.336721927603217
# differential_evolution step 726: f(x)= 2.336721927603217
# differential_evolution step 727: f(x)= 2.336721927603217
# differential_evolution step 728: f(x)= 2.336721927603217
# differential_evolution step 729: f(x)= 2.336721927603217
# differential_evolution step 730: f(x)= 2.336721927603217
# differential_evolution step 731: f(x)= 2.336721927603217
# differential_evolution step 732: f(x)= 2.336721927603217
# differential_evolution step 733: f(x)= 2.336721110725672
# differential_evolution step 734: f(x)= 2.336721110725672
# differential_evolution step 735: f(x)= 2.336721110725672
# differential_evolution step 736: f(x)= 2.336721110725672
# differential_evolution step 737: f(x)= 2.336721110725672
# differential_evolution step 738: f(x)= 2.336721110725672
# differential_evolution step 739: f(x)= 2.336721110725672
# differential_evolution step 740: f(x)= 2.336721110725672
# differential_evolution step 741: f(x)= 2.336721110725672
# differential_evolution step 742: f(x)= 2.336721110725672
# differential_evolution step 743: f(x)= 2.336721110725672
# differential_evolution step 744: f(x)= 2.336721110725672
# differential_evolution step 745: f(x)= 2.336721110725672
# differential_evolution step 746: f(x)= 2.336720688918458
# differential_evolution step 747: f(x)= 2.336720688918458
# differential_evolution step 748: f(x)= 2.336720688918458
# differential_evolution step 749: f(x)= 2.336720688918458
# differential_evolution step 750: f(x)= 2.336720688918458
# differential_evolution step 751: f(x)= 2.336720688918458
# differential_evolution step 752: f(x)= 2.336720688918458
# differential_evolution step 753: f(x)= 2.336720688918458
# differential_evolution step 754: f(x)= 2.336720688918458
# differential_evolution step 755: f(x)= 2.336720688918458
# differential_evolution step 756: f(x)= 2.336720688918458
# differential_evolution step 757: f(x)= 2.336720581757753
# differential_evolution step 758: f(x)= 2.336720581757753
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=9.3609, r_e=2.7884, n=0.4555, x_0=39.8378
# Sérsic 2: I_e=0.5086, r_e=17.2899, n=1.5260, x_0=48.1820
# Sérsic 3: I_e=1.1499, r_e=2.7981, n=0.8505, x_0=57.5979
# Chi quadro minimo: 2.336719527832346
# True

# %%
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 45),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 54),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (54, 65)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, radial_profile_error_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=8.5746, r_e=2.9582, n=0.5240, x_0=39.8764
# Sérsic 2: I_e=0.3963, r_e=18.2281, n=1.6886, x_0=48.2716
# Sérsic 3: I_e=0.8942, r_e=3.7153, n=1.0279, x_0=57.5728
# [0.21639142 0.04655988 0.01893122 0.02585423 0.05575373 1.37375442
#  0.10030836 0.07915693 0.15901265 0.49461103 0.13073641 0.06922531]
# 10.343848539059142

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 9937.031756517008
# differential_evolution step 2: f(x)= 2210.701928803579
# differential_evolution step 3: f(x)= 1948.8292582694146
# differential_evolution step 4: f(x)= 429.4809688387743
# differential_evolution step 5: f(x)= 429.4809688387743
# differential_evolution step 6: f(x)= 429.4809688387743
# differential_evolution step 7: f(x)= 429.4809688387743
# differential_evolution step 8: f(x)= 428.7932986691455
# differential_evolution step 9: f(x)= 380.18034932439787
# differential_evolution step 10: f(x)= 223.60064133336013
# differential_evolution step 11: f(x)= 223.60064133336013
# differential_evolution step 12: f(x)= 148.83180751295822
# differential_evolution step 13: f(x)= 148.83180751295822
# differential_evolution step 14: f(x)= 148.83180751295822
# differential_evolution step 15: f(x)= 148.83180751295822
# differential_evolution step 16: f(x)= 116.8964380024205
# differential_evolution step 17: f(x)= 116.8964380024205
# differential_evolution step 18: f(x)= 116.8964380024205
# differential_evolution step 19: f(x)= 116.8964380024205
# differential_evolution step 20: f(x)= 97.60249177759977
# differential_evolution step 21: f(x)= 97.60249177759977
# differential_evolution step 22: f(x)= 97.60249177759977
# differential_evolution step 23: f(x)= 97.60249177759977
# differential_evolution step 24: f(x)= 97.60249177759977
# differential_evolution step 25: f(x)= 97.60249177759977
# differential_evolution step 26: f(x)= 90.76710139339752
# differential_evolution step 27: f(x)= 75.26293555183717
# differential_evolution step 28: f(x)= 75.26293555183717
# differential_evolution step 29: f(x)= 75.26293555183717
# differential_evolution step 30: f(x)= 75.26293555183717
# differential_evolution step 31: f(x)= 75.26293555183717
# differential_evolution step 32: f(x)= 75.26293555183717
# differential_evolution step 33: f(x)= 75.26293555183717
# differential_evolution step 34: f(x)= 69.66788506977682
# differential_evolution step 35: f(x)= 55.332414068250145
# differential_evolution step 36: f(x)= 51.02169912868593
# differential_evolution step 37: f(x)= 51.02169912868593
# differential_evolution step 38: f(x)= 51.02169912868593
# differential_evolution step 39: f(x)= 42.43411788860809
# differential_evolution step 40: f(x)= 42.43411788860809
# differential_evolution step 41: f(x)= 35.87299672520228
# differential_evolution step 42: f(x)= 35.87299672520228
# differential_evolution step 43: f(x)= 35.87299672520228
# differential_evolution step 44: f(x)= 35.87299672520228
# differential_evolution step 45: f(x)= 32.19720277805517
# differential_evolution step 46: f(x)= 32.19720277805517
# differential_evolution step 47: f(x)= 32.19720277805517
# differential_evolution step 48: f(x)= 29.102333376388362
# differential_evolution step 49: f(x)= 29.102333376388362
# differential_evolution step 50: f(x)= 29.102333376388362
# differential_evolution step 51: f(x)= 29.102333376388362
# differential_evolution step 52: f(x)= 29.102333376388362
# differential_evolution step 53: f(x)= 29.102333376388362
# differential_evolution step 54: f(x)= 29.102333376388362
# differential_evolution step 55: f(x)= 29.102333376388362
# differential_evolution step 56: f(x)= 28.229965690150337
# differential_evolution step 57: f(x)= 28.229965690150337
# differential_evolution step 58: f(x)= 28.229965690150337
# differential_evolution step 59: f(x)= 28.046907448585376
# differential_evolution step 60: f(x)= 28.046907448585376
# differential_evolution step 61: f(x)= 26.235509473266614
# differential_evolution step 62: f(x)= 26.235509473266614
# differential_evolution step 63: f(x)= 26.235509473266614
# differential_evolution step 64: f(x)= 26.235509473266614
# differential_evolution step 65: f(x)= 26.235509473266614
# differential_evolution step 66: f(x)= 26.235509473266614
# differential_evolution step 67: f(x)= 24.602854262196836
# differential_evolution step 68: f(x)= 24.602854262196836
# differential_evolution step 69: f(x)= 24.602854262196836
# differential_evolution step 70: f(x)= 24.602854262196836
# differential_evolution step 71: f(x)= 20.6014095033694
# differential_evolution step 72: f(x)= 20.6014095033694
# differential_evolution step 73: f(x)= 20.6014095033694
# differential_evolution step 74: f(x)= 20.6014095033694
# differential_evolution step 75: f(x)= 20.6014095033694
# differential_evolution step 76: f(x)= 20.496235420887828
# differential_evolution step 77: f(x)= 19.898325008759045
# differential_evolution step 78: f(x)= 19.898325008759045
# differential_evolution step 79: f(x)= 19.898325008759045
# differential_evolution step 80: f(x)= 19.898325008759045
# differential_evolution step 81: f(x)= 19.898325008759045
# differential_evolution step 82: f(x)= 19.898325008759045
# differential_evolution step 83: f(x)= 16.96587422333952
# differential_evolution step 84: f(x)= 16.96587422333952
# differential_evolution step 85: f(x)= 16.96587422333952
# differential_evolution step 86: f(x)= 16.96587422333952
# differential_evolution step 87: f(x)= 16.96587422333952
# differential_evolution step 88: f(x)= 16.96587422333952
# differential_evolution step 89: f(x)= 16.96587422333952
# differential_evolution step 90: f(x)= 16.96587422333952
# differential_evolution step 91: f(x)= 16.96587422333952
# differential_evolution step 92: f(x)= 16.96587422333952
# differential_evolution step 93: f(x)= 16.96587422333952
# differential_evolution step 94: f(x)= 16.96587422333952
# differential_evolution step 95: f(x)= 16.96587422333952
# differential_evolution step 96: f(x)= 16.96587422333952
# differential_evolution step 97: f(x)= 16.96587422333952
# differential_evolution step 98: f(x)= 16.767361253915382
# differential_evolution step 99: f(x)= 16.767361253915382
# differential_evolution step 100: f(x)= 16.767361253915382
# differential_evolution step 101: f(x)= 16.767361253915382
# differential_evolution step 102: f(x)= 16.767361253915382
# differential_evolution step 103: f(x)= 16.767361253915382
# differential_evolution step 104: f(x)= 16.767361253915382
# differential_evolution step 105: f(x)= 16.767361253915382
# differential_evolution step 106: f(x)= 16.56627199265037
# differential_evolution step 107: f(x)= 16.56627199265037
# differential_evolution step 108: f(x)= 16.56627199265037
# differential_evolution step 109: f(x)= 16.56627199265037
# differential_evolution step 110: f(x)= 15.329813343182026
# differential_evolution step 111: f(x)= 14.12811626773513
# differential_evolution step 112: f(x)= 13.130841306891393
# differential_evolution step 113: f(x)= 13.130841306891393
# differential_evolution step 114: f(x)= 13.130841306891393
# differential_evolution step 115: f(x)= 13.130841306891393
# differential_evolution step 116: f(x)= 13.090883627366804
# differential_evolution step 117: f(x)= 12.598892382564406
# differential_evolution step 118: f(x)= 10.9670763681698
# differential_evolution step 119: f(x)= 10.9670763681698
# differential_evolution step 120: f(x)= 10.9670763681698
# differential_evolution step 121: f(x)= 10.9670763681698
# differential_evolution step 122: f(x)= 10.632231618355739
# differential_evolution step 123: f(x)= 10.632231618355739
# differential_evolution step 124: f(x)= 10.632231618355739
# differential_evolution step 125: f(x)= 10.632231618355739
# differential_evolution step 126: f(x)= 10.632231618355739
# differential_evolution step 127: f(x)= 10.632231618355739
# differential_evolution step 128: f(x)= 10.632231618355739
# differential_evolution step 129: f(x)= 10.52937799819528
# differential_evolution step 130: f(x)= 10.52937799819528
# differential_evolution step 131: f(x)= 10.52937799819528
# differential_evolution step 132: f(x)= 10.290292710209837
# differential_evolution step 133: f(x)= 8.920070278973443
# differential_evolution step 134: f(x)= 8.920070278973443
# differential_evolution step 135: f(x)= 8.920070278973443
# differential_evolution step 136: f(x)= 8.920070278973443
# differential_evolution step 137: f(x)= 8.339558615149905
# differential_evolution step 138: f(x)= 8.339558615149905
# differential_evolution step 139: f(x)= 8.339558615149905
# differential_evolution step 140: f(x)= 8.339558615149905
# differential_evolution step 141: f(x)= 8.339558615149905
# differential_evolution step 142: f(x)= 7.4830463177412625
# differential_evolution step 143: f(x)= 6.944930722928252
# differential_evolution step 144: f(x)= 6.944930722928252
# differential_evolution step 145: f(x)= 6.944930722928252
# differential_evolution step 146: f(x)= 6.944930722928252
# differential_evolution step 147: f(x)= 6.944930722928252
# differential_evolution step 148: f(x)= 6.944930722928252
# differential_evolution step 149: f(x)= 6.944930722928252
# differential_evolution step 150: f(x)= 6.944930722928252
# differential_evolution step 151: f(x)= 6.944930722928252
# differential_evolution step 152: f(x)= 6.944930722928252
# differential_evolution step 153: f(x)= 6.944930722928252
# differential_evolution step 154: f(x)= 6.944930722928252
# differential_evolution step 155: f(x)= 6.903976799079607
# differential_evolution step 156: f(x)= 6.828881916470206
# differential_evolution step 157: f(x)= 6.09322161296459
# differential_evolution step 158: f(x)= 6.09322161296459
# differential_evolution step 159: f(x)= 6.09322161296459
# differential_evolution step 160: f(x)= 6.09322161296459
# differential_evolution step 161: f(x)= 6.09322161296459
# differential_evolution step 162: f(x)= 6.09322161296459
# differential_evolution step 163: f(x)= 6.09322161296459
# differential_evolution step 164: f(x)= 6.09322161296459
# differential_evolution step 165: f(x)= 6.09322161296459
# differential_evolution step 166: f(x)= 6.058026542818035
# differential_evolution step 167: f(x)= 6.058026542818035
# differential_evolution step 168: f(x)= 6.058026542818035
# differential_evolution step 169: f(x)= 6.058026542818035
# differential_evolution step 170: f(x)= 6.058026542818035
# differential_evolution step 171: f(x)= 6.058026542818035
# differential_evolution step 172: f(x)= 6.058026542818035
# differential_evolution step 173: f(x)= 6.058026542818035
# differential_evolution step 174: f(x)= 6.058026542818035
# differential_evolution step 175: f(x)= 6.058026542818035
# differential_evolution step 176: f(x)= 6.058026542818035
# differential_evolution step 177: f(x)= 6.058026542818035
# differential_evolution step 178: f(x)= 6.058026542818035
# differential_evolution step 179: f(x)= 5.999560119354196
# differential_evolution step 180: f(x)= 5.999560119354196
# differential_evolution step 181: f(x)= 5.999560119354196
# differential_evolution step 182: f(x)= 5.999560119354196
# differential_evolution step 183: f(x)= 5.999560119354196
# differential_evolution step 184: f(x)= 5.999560119354196
# differential_evolution step 185: f(x)= 5.999560119354196
# differential_evolution step 186: f(x)= 5.999560119354196
# differential_evolution step 187: f(x)= 5.999560119354196
# differential_evolution step 188: f(x)= 5.999560119354196
# differential_evolution step 189: f(x)= 5.6702026507385535
# differential_evolution step 190: f(x)= 5.6702026507385535
# differential_evolution step 191: f(x)= 5.6702026507385535
# differential_evolution step 192: f(x)= 5.6702026507385535
# differential_evolution step 193: f(x)= 5.6702026507385535
# differential_evolution step 194: f(x)= 5.6702026507385535
# differential_evolution step 195: f(x)= 5.6702026507385535
# differential_evolution step 196: f(x)= 5.6702026507385535
# differential_evolution step 197: f(x)= 5.6702026507385535
# differential_evolution step 198: f(x)= 5.6702026507385535
# differential_evolution step 199: f(x)= 5.6702026507385535
# differential_evolution step 200: f(x)= 5.6702026507385535
# differential_evolution step 201: f(x)= 5.6702026507385535
# differential_evolution step 202: f(x)= 5.6702026507385535
# differential_evolution step 203: f(x)= 5.6702026507385535
# differential_evolution step 204: f(x)= 5.6702026507385535
# differential_evolution step 205: f(x)= 5.6702026507385535
# differential_evolution step 206: f(x)= 5.6702026507385535
# differential_evolution step 207: f(x)= 5.6702026507385535
# differential_evolution step 208: f(x)= 5.6702026507385535
# differential_evolution step 209: f(x)= 5.6702026507385535
# differential_evolution step 210: f(x)= 5.6702026507385535
# differential_evolution step 211: f(x)= 5.6702026507385535
# differential_evolution step 212: f(x)= 5.6702026507385535
# differential_evolution step 213: f(x)= 5.6702026507385535
# differential_evolution step 214: f(x)= 5.6702026507385535
# differential_evolution step 215: f(x)= 5.6702026507385535
# differential_evolution step 216: f(x)= 5.6702026507385535
# differential_evolution step 217: f(x)= 5.6702026507385535
# differential_evolution step 218: f(x)= 5.6702026507385535
# differential_evolution step 219: f(x)= 5.6702026507385535
# differential_evolution step 220: f(x)= 5.667248921109796
# differential_evolution step 221: f(x)= 5.667248921109796
# differential_evolution step 222: f(x)= 5.667248921109796
# differential_evolution step 223: f(x)= 5.644745640095162
# differential_evolution step 224: f(x)= 5.590207578478228
# differential_evolution step 225: f(x)= 5.590207578478228
# differential_evolution step 226: f(x)= 5.590207578478228
# differential_evolution step 227: f(x)= 5.590207578478228
# differential_evolution step 228: f(x)= 5.590207578478228
# differential_evolution step 229: f(x)= 5.590207578478228
# differential_evolution step 230: f(x)= 5.590207578478228
# differential_evolution step 231: f(x)= 5.537655647606495
# differential_evolution step 232: f(x)= 5.537655647606495
# differential_evolution step 233: f(x)= 5.537655647606495
# differential_evolution step 234: f(x)= 5.537655647606495
# differential_evolution step 235: f(x)= 5.537655647606495
# differential_evolution step 236: f(x)= 5.537655647606495
# differential_evolution step 237: f(x)= 5.493746285308879
# differential_evolution step 238: f(x)= 5.493746285308879
# differential_evolution step 239: f(x)= 5.493746285308879
# differential_evolution step 240: f(x)= 5.491572266405531
# differential_evolution step 241: f(x)= 5.491572266405531
# differential_evolution step 242: f(x)= 5.491572266405531
# differential_evolution step 243: f(x)= 5.478957067665063
# differential_evolution step 244: f(x)= 5.447770982925902
# differential_evolution step 245: f(x)= 5.447770982925902
# differential_evolution step 246: f(x)= 5.447770982925902
# differential_evolution step 247: f(x)= 5.443197884731858
# differential_evolution step 248: f(x)= 5.443197884731858
# differential_evolution step 249: f(x)= 5.443197884731858
# differential_evolution step 250: f(x)= 5.443197884731858
# differential_evolution step 251: f(x)= 5.443197884731858
# differential_evolution step 252: f(x)= 5.443197884731858
# differential_evolution step 253: f(x)= 5.443197884731858
# differential_evolution step 254: f(x)= 5.443197884731858
# differential_evolution step 255: f(x)= 5.384279179579031
# differential_evolution step 256: f(x)= 5.384279179579031
# differential_evolution step 257: f(x)= 5.384279179579031
# differential_evolution step 258: f(x)= 5.352451815776354
# differential_evolution step 259: f(x)= 5.352451815776354
# differential_evolution step 260: f(x)= 5.311171692810207
# differential_evolution step 261: f(x)= 5.311171692810207
# differential_evolution step 262: f(x)= 5.311171692810207
# differential_evolution step 263: f(x)= 5.311171692810207
# differential_evolution step 264: f(x)= 5.311171692810207
# differential_evolution step 265: f(x)= 5.311171692810207
# differential_evolution step 266: f(x)= 5.299835967063699
# differential_evolution step 267: f(x)= 5.299835967063699
# differential_evolution step 268: f(x)= 5.299835967063699
# differential_evolution step 269: f(x)= 5.299835967063699
# differential_evolution step 270: f(x)= 5.299835967063699
# differential_evolution step 271: f(x)= 5.299835967063699
# differential_evolution step 272: f(x)= 5.299835967063699
# differential_evolution step 273: f(x)= 5.299835967063699
# differential_evolution step 274: f(x)= 5.296024106899581
# differential_evolution step 275: f(x)= 5.296024106899581
# differential_evolution step 276: f(x)= 5.296024106899581
# differential_evolution step 277: f(x)= 5.289829430595737
# differential_evolution step 278: f(x)= 5.27519460088074
# differential_evolution step 279: f(x)= 5.27519460088074
# differential_evolution step 280: f(x)= 5.27519460088074
# differential_evolution step 281: f(x)= 5.27519460088074
# differential_evolution step 282: f(x)= 5.27519460088074
# differential_evolution step 283: f(x)= 5.27519460088074
# differential_evolution step 284: f(x)= 5.27519460088074
# differential_evolution step 285: f(x)= 5.27519460088074
# differential_evolution step 286: f(x)= 5.27519460088074
# differential_evolution step 287: f(x)= 5.27519460088074
# differential_evolution step 288: f(x)= 5.27519460088074
# differential_evolution step 289: f(x)= 5.27519460088074
# differential_evolution step 290: f(x)= 5.27519460088074
# differential_evolution step 291: f(x)= 5.097510509425028
# differential_evolution step 292: f(x)= 5.097510509425028
# differential_evolution step 293: f(x)= 5.097510509425028
# differential_evolution step 294: f(x)= 5.097510509425028
# differential_evolution step 295: f(x)= 5.097510509425028
# differential_evolution step 296: f(x)= 5.097510509425028
# differential_evolution step 297: f(x)= 5.097510509425028
# differential_evolution step 298: f(x)= 5.097510509425028
# differential_evolution step 299: f(x)= 5.059330356624034
# differential_evolution step 300: f(x)= 5.059330356624034
# differential_evolution step 301: f(x)= 5.03441617818292
# differential_evolution step 302: f(x)= 5.0098283896885185
# differential_evolution step 303: f(x)= 4.99919708361516
# differential_evolution step 304: f(x)= 4.99919708361516
# differential_evolution step 305: f(x)= 4.851381903447444
# differential_evolution step 306: f(x)= 4.728670786909737
# differential_evolution step 307: f(x)= 4.726046910196792
# differential_evolution step 308: f(x)= 4.726046910196792
# differential_evolution step 309: f(x)= 4.726046910196792
# differential_evolution step 310: f(x)= 4.726046910196792
# differential_evolution step 311: f(x)= 4.726046910196792
# differential_evolution step 312: f(x)= 4.564778045744635
# differential_evolution step 313: f(x)= 4.564778045744635
# differential_evolution step 314: f(x)= 4.564778045744635
# differential_evolution step 315: f(x)= 4.564778045744635
# differential_evolution step 316: f(x)= 4.564778045744635
# differential_evolution step 317: f(x)= 4.564778045744635
# differential_evolution step 318: f(x)= 4.552291577057073
# differential_evolution step 319: f(x)= 4.552291577057073
# differential_evolution step 320: f(x)= 4.552291577057073
# differential_evolution step 321: f(x)= 4.483750937735769
# differential_evolution step 322: f(x)= 4.4425209439591224
# differential_evolution step 323: f(x)= 4.4425209439591224
# differential_evolution step 324: f(x)= 4.4425209439591224
# differential_evolution step 325: f(x)= 4.4425209439591224
# differential_evolution step 326: f(x)= 4.4425209439591224
# differential_evolution step 327: f(x)= 4.423133911958974
# differential_evolution step 328: f(x)= 4.423133911958974
# differential_evolution step 329: f(x)= 4.423133911958974
# differential_evolution step 330: f(x)= 4.423133911958974
# differential_evolution step 331: f(x)= 4.423133911958974
# differential_evolution step 332: f(x)= 4.423133911958974
# differential_evolution step 333: f(x)= 4.423133911958974
# differential_evolution step 334: f(x)= 4.423133911958974
# differential_evolution step 335: f(x)= 4.423133911958974
# differential_evolution step 336: f(x)= 4.379381271222497
# differential_evolution step 337: f(x)= 4.283457474916738
# differential_evolution step 338: f(x)= 4.283457474916738
# differential_evolution step 339: f(x)= 4.25230829664297
# differential_evolution step 340: f(x)= 4.25230829664297
# differential_evolution step 341: f(x)= 4.25230829664297
# differential_evolution step 342: f(x)= 4.25230829664297
# differential_evolution step 343: f(x)= 4.25230829664297
# differential_evolution step 344: f(x)= 4.25230829664297
# differential_evolution step 345: f(x)= 4.25230829664297
# differential_evolution step 346: f(x)= 4.25230829664297
# differential_evolution step 347: f(x)= 4.25230829664297
# differential_evolution step 348: f(x)= 4.25230829664297
# differential_evolution step 349: f(x)= 4.25230829664297
# differential_evolution step 350: f(x)= 4.25230829664297
# differential_evolution step 351: f(x)= 4.25230829664297
# differential_evolution step 352: f(x)= 4.25230829664297
# differential_evolution step 353: f(x)= 4.25230829664297
# differential_evolution step 354: f(x)= 4.25230829664297
# differential_evolution step 355: f(x)= 4.25230829664297
# differential_evolution step 356: f(x)= 4.25230829664297
# differential_evolution step 357: f(x)= 4.244343881938445
# differential_evolution step 358: f(x)= 4.244343881938445
# differential_evolution step 359: f(x)= 4.244343881938445
# differential_evolution step 360: f(x)= 4.244343881938445
# differential_evolution step 361: f(x)= 4.244343881938445
# differential_evolution step 362: f(x)= 4.244343881938445
# differential_evolution step 363: f(x)= 4.244343881938445
# differential_evolution step 364: f(x)= 4.244343881938445
# differential_evolution step 365: f(x)= 4.244343881938445
# differential_evolution step 366: f(x)= 4.244343881938445
# differential_evolution step 367: f(x)= 4.244343881938445
# differential_evolution step 368: f(x)= 4.243584704324072
# differential_evolution step 369: f(x)= 4.243584704324072
# differential_evolution step 370: f(x)= 4.243584704324072
# differential_evolution step 371: f(x)= 4.243584704324072
# differential_evolution step 372: f(x)= 4.243584704324072
# differential_evolution step 373: f(x)= 4.243584704324072
# differential_evolution step 374: f(x)= 4.243584704324072
# differential_evolution step 375: f(x)= 4.243584704324072
# differential_evolution step 376: f(x)= 4.243584704324072
# differential_evolution step 377: f(x)= 4.243584704324072
# differential_evolution step 378: f(x)= 4.243584704324072
# differential_evolution step 379: f(x)= 4.243584704324072
# differential_evolution step 380: f(x)= 4.243584704324072
# differential_evolution step 381: f(x)= 4.243584704324072
# differential_evolution step 382: f(x)= 4.243584704324072
# differential_evolution step 383: f(x)= 4.243584704324072
# differential_evolution step 384: f(x)= 4.243584704324072
# differential_evolution step 385: f(x)= 4.243584704324072
# differential_evolution step 386: f(x)= 4.243584704324072
# differential_evolution step 387: f(x)= 4.243584704324072
# differential_evolution step 388: f(x)= 4.243584704324072
# differential_evolution step 389: f(x)= 4.243584704324072
# differential_evolution step 390: f(x)= 4.243584704324072
# differential_evolution step 391: f(x)= 4.175581488751815
# differential_evolution step 392: f(x)= 4.175581488751815
# differential_evolution step 393: f(x)= 4.175581488751815
# differential_evolution step 394: f(x)= 4.175581488751815
# differential_evolution step 395: f(x)= 4.175581488751815
# differential_evolution step 396: f(x)= 4.1739318709060385
# differential_evolution step 397: f(x)= 4.167769129085448
# differential_evolution step 398: f(x)= 4.167769129085448
# differential_evolution step 399: f(x)= 4.167769129085448
# differential_evolution step 400: f(x)= 4.167769129085448
# differential_evolution step 401: f(x)= 4.148722840530321
# differential_evolution step 402: f(x)= 4.148722840530321
# differential_evolution step 403: f(x)= 4.148722840530321
# differential_evolution step 404: f(x)= 4.148722840530321
# differential_evolution step 405: f(x)= 4.148722840530321
# differential_evolution step 406: f(x)= 4.148722840530321
# differential_evolution step 407: f(x)= 4.141505317584652
# differential_evolution step 408: f(x)= 4.141505317584652
# differential_evolution step 409: f(x)= 4.135166296984991
# differential_evolution step 410: f(x)= 4.135166296984991
# differential_evolution step 411: f(x)= 4.092774856087001
# differential_evolution step 412: f(x)= 4.092774856087001
# differential_evolution step 413: f(x)= 4.092774856087001
# differential_evolution step 414: f(x)= 4.092774856087001
# differential_evolution step 415: f(x)= 4.092774856087001
# differential_evolution step 416: f(x)= 4.092774856087001
# differential_evolution step 417: f(x)= 4.092774856087001
# differential_evolution step 418: f(x)= 4.092774856087001
# differential_evolution step 419: f(x)= 4.092774856087001
# differential_evolution step 420: f(x)= 4.092774856087001
# differential_evolution step 421: f(x)= 4.092774856087001
# differential_evolution step 422: f(x)= 4.092774856087001
# differential_evolution step 423: f(x)= 4.092774856087001
# differential_evolution step 424: f(x)= 4.092774856087001
# differential_evolution step 425: f(x)= 4.092774856087001
# differential_evolution step 426: f(x)= 4.092774856087001
# differential_evolution step 427: f(x)= 4.092774856087001
# differential_evolution step 428: f(x)= 4.092774856087001
# differential_evolution step 429: f(x)= 4.086280849944965
# differential_evolution step 430: f(x)= 4.086280849944965
# differential_evolution step 431: f(x)= 4.072299096211079
# differential_evolution step 432: f(x)= 4.072299096211079
# differential_evolution step 433: f(x)= 4.051193675067167
# differential_evolution step 434: f(x)= 4.051193675067167
# differential_evolution step 435: f(x)= 4.051193675067167
# differential_evolution step 436: f(x)= 4.051193675067167
# differential_evolution step 437: f(x)= 4.051193675067167
# differential_evolution step 438: f(x)= 4.051193675067167
# differential_evolution step 439: f(x)= 4.051193675067167
# differential_evolution step 440: f(x)= 4.051193675067167
# differential_evolution step 441: f(x)= 4.051193675067167
# differential_evolution step 442: f(x)= 4.051193675067167
# differential_evolution step 443: f(x)= 4.0457264917648414
# differential_evolution step 444: f(x)= 4.0457264917648414
# differential_evolution step 445: f(x)= 4.044126484485253
# differential_evolution step 446: f(x)= 4.044126484485253
# differential_evolution step 447: f(x)= 4.044126484485253
# differential_evolution step 448: f(x)= 4.044126484485253
# differential_evolution step 449: f(x)= 4.044126484485253
# differential_evolution step 450: f(x)= 4.044126484485253
# differential_evolution step 451: f(x)= 4.017786677732855
# differential_evolution step 452: f(x)= 4.017786677732855
# differential_evolution step 453: f(x)= 4.014305528702312
# differential_evolution step 454: f(x)= 4.014305528702312
# differential_evolution step 455: f(x)= 4.012520045510072
# differential_evolution step 456: f(x)= 4.012520045510072
# differential_evolution step 457: f(x)= 4.012520045510072
# differential_evolution step 458: f(x)= 4.012520045510072
# differential_evolution step 459: f(x)= 4.012520045510072
# differential_evolution step 460: f(x)= 4.012520045510072
# differential_evolution step 461: f(x)= 4.012520045510072
# differential_evolution step 462: f(x)= 4.012520045510072
# differential_evolution step 463: f(x)= 4.012520045510072
# differential_evolution step 464: f(x)= 4.0047142313273545
# differential_evolution step 465: f(x)= 4.0047142313273545
# differential_evolution step 466: f(x)= 4.0047142313273545
# differential_evolution step 467: f(x)= 4.0047142313273545
# differential_evolution step 468: f(x)= 4.0047142313273545
# differential_evolution step 469: f(x)= 4.0047142313273545
# differential_evolution step 470: f(x)= 4.0047142313273545
# differential_evolution step 471: f(x)= 4.003963640524168
# differential_evolution step 472: f(x)= 3.9792300497397486
# differential_evolution step 473: f(x)= 3.9792300497397486
# differential_evolution step 474: f(x)= 3.9792300497397486
# differential_evolution step 475: f(x)= 3.9792300497397486
# differential_evolution step 476: f(x)= 3.9792300497397486
# differential_evolution step 477: f(x)= 3.9792300497397486
# differential_evolution step 478: f(x)= 3.9792300497397486
# differential_evolution step 479: f(x)= 3.9671346807046755
# differential_evolution step 480: f(x)= 3.9671346807046755
# differential_evolution step 481: f(x)= 3.96344491978202
# differential_evolution step 482: f(x)= 3.96344491978202
# differential_evolution step 483: f(x)= 3.96344491978202
# differential_evolution step 484: f(x)= 3.96344491978202
# differential_evolution step 485: f(x)= 3.9508775328738923
# differential_evolution step 486: f(x)= 3.9508775328738923
# differential_evolution step 487: f(x)= 3.9508775328738923
# differential_evolution step 488: f(x)= 3.943566247527517
# differential_evolution step 489: f(x)= 3.9285069978043428
# differential_evolution step 490: f(x)= 3.9285069978043428
# differential_evolution step 491: f(x)= 3.9285069978043428
# differential_evolution step 492: f(x)= 3.9285069978043428
# differential_evolution step 493: f(x)= 3.9285069978043428
# differential_evolution step 494: f(x)= 3.9285069978043428
# differential_evolution step 495: f(x)= 3.9285069978043428
# differential_evolution step 496: f(x)= 3.9285069978043428
# differential_evolution step 497: f(x)= 3.9285069978043428
# differential_evolution step 498: f(x)= 3.9285069978043428
# differential_evolution step 499: f(x)= 3.9285069978043428
# differential_evolution step 500: f(x)= 3.9285069978043428
# differential_evolution step 501: f(x)= 3.9285069978043428
# differential_evolution step 502: f(x)= 3.9285069978043428
# differential_evolution step 503: f(x)= 3.9285069978043428
# differential_evolution step 504: f(x)= 3.9285069978043428
# differential_evolution step 505: f(x)= 3.9285069978043428
# differential_evolution step 506: f(x)= 3.9242611278565036
# differential_evolution step 507: f(x)= 3.8981547437357986
# differential_evolution step 508: f(x)= 3.8981547437357986
# differential_evolution step 509: f(x)= 3.8981547437357986
# differential_evolution step 510: f(x)= 3.8981547437357986
# differential_evolution step 511: f(x)= 3.8804678575268405
# differential_evolution step 512: f(x)= 3.8743288979620223
# differential_evolution step 513: f(x)= 3.8743288979620223
# differential_evolution step 514: f(x)= 3.8743288979620223
# differential_evolution step 515: f(x)= 3.8743288979620223
# differential_evolution step 516: f(x)= 3.8743288979620223
# differential_evolution step 517: f(x)= 3.857258461078804
# differential_evolution step 518: f(x)= 3.857258461078804
# differential_evolution step 519: f(x)= 3.857258461078804
# differential_evolution step 520: f(x)= 3.857258461078804
# differential_evolution step 521: f(x)= 3.857258461078804
# differential_evolution step 522: f(x)= 3.857258461078804
# differential_evolution step 523: f(x)= 3.857258461078804
# differential_evolution step 524: f(x)= 3.857258461078804
# differential_evolution step 525: f(x)= 3.857258461078804
# differential_evolution step 526: f(x)= 3.857258461078804
# differential_evolution step 527: f(x)= 3.857258461078804
# differential_evolution step 528: f(x)= 3.857258461078804
# differential_evolution step 529: f(x)= 3.857258461078804
# differential_evolution step 530: f(x)= 3.857258461078804
# differential_evolution step 531: f(x)= 3.8552194567699205
# differential_evolution step 532: f(x)= 3.8552194567699205
# differential_evolution step 533: f(x)= 3.8552194567699205
# differential_evolution step 534: f(x)= 3.8552194567699205
# differential_evolution step 535: f(x)= 3.8552194567699205
# differential_evolution step 536: f(x)= 3.8552194567699205
# differential_evolution step 537: f(x)= 3.8552194567699205
# differential_evolution step 538: f(x)= 3.8496539495322324
# differential_evolution step 539: f(x)= 3.8496539495322324
# differential_evolution step 540: f(x)= 3.8496539495322324
# differential_evolution step 541: f(x)= 3.825862207206981
# differential_evolution step 542: f(x)= 3.8188325936639758
# differential_evolution step 543: f(x)= 3.8188325936639758
# differential_evolution step 544: f(x)= 3.8188325936639758
# differential_evolution step 545: f(x)= 3.8188325936639758
# differential_evolution step 546: f(x)= 3.8188325936639758
# differential_evolution step 547: f(x)= 3.8188325936639758
# differential_evolution step 548: f(x)= 3.8188325936639758
# differential_evolution step 549: f(x)= 3.8188325936639758
# differential_evolution step 550: f(x)= 3.8188325936639758
# differential_evolution step 551: f(x)= 3.8188325936639758
# differential_evolution step 552: f(x)= 3.8188325936639758
# differential_evolution step 553: f(x)= 3.8188325936639758
# differential_evolution step 554: f(x)= 3.817714253470107
# differential_evolution step 555: f(x)= 3.817714253470107
# differential_evolution step 556: f(x)= 3.817714253470107
# differential_evolution step 557: f(x)= 3.817714253470107
# differential_evolution step 558: f(x)= 3.817714253470107
# differential_evolution step 559: f(x)= 3.817714253470107
# differential_evolution step 560: f(x)= 3.817714253470107
# differential_evolution step 561: f(x)= 3.817714253470107
# differential_evolution step 562: f(x)= 3.814735303646403
# differential_evolution step 563: f(x)= 3.814735303646403
# differential_evolution step 564: f(x)= 3.814735303646403
# differential_evolution step 565: f(x)= 3.814735303646403
# differential_evolution step 566: f(x)= 3.814735303646403
# differential_evolution step 567: f(x)= 3.814735303646403
# differential_evolution step 568: f(x)= 3.814735303646403
# differential_evolution step 569: f(x)= 3.814735303646403
# differential_evolution step 570: f(x)= 3.809288683141436
# differential_evolution step 571: f(x)= 3.809288683141436
# differential_evolution step 572: f(x)= 3.809288683141436
# differential_evolution step 573: f(x)= 3.809288683141436
# differential_evolution step 574: f(x)= 3.80736723596784
# differential_evolution step 575: f(x)= 3.798138102303781
# differential_evolution step 576: f(x)= 3.798138102303781
# differential_evolution step 577: f(x)= 3.7936445513070334
# differential_evolution step 578: f(x)= 3.7935788449502583
# differential_evolution step 579: f(x)= 3.7935788449502583
# differential_evolution step 580: f(x)= 3.791010384719851
# differential_evolution step 581: f(x)= 3.788893377046348
# differential_evolution step 582: f(x)= 3.788893377046348
# differential_evolution step 583: f(x)= 3.788893377046348
# differential_evolution step 584: f(x)= 3.788893377046348
# differential_evolution step 585: f(x)= 3.7840510959749443
# differential_evolution step 586: f(x)= 3.78133210155497
# differential_evolution step 587: f(x)= 3.78133210155497
# differential_evolution step 588: f(x)= 3.78133210155497
# differential_evolution step 589: f(x)= 3.78133210155497
# differential_evolution step 590: f(x)= 3.78133210155497
# differential_evolution step 591: f(x)= 3.78133210155497
# differential_evolution step 592: f(x)= 3.78133210155497
# differential_evolution step 593: f(x)= 3.78133210155497
# differential_evolution step 594: f(x)= 3.78133210155497
# differential_evolution step 595: f(x)= 3.78133210155497
# differential_evolution step 596: f(x)= 3.78133210155497
# differential_evolution step 597: f(x)= 3.78133210155497
# differential_evolution step 598: f(x)= 3.7757756560168514
# differential_evolution step 599: f(x)= 3.7757756560168514
# differential_evolution step 600: f(x)= 3.7757756560168514
# differential_evolution step 601: f(x)= 3.7757756560168514
# differential_evolution step 602: f(x)= 3.7757756560168514
# differential_evolution step 603: f(x)= 3.7757756560168514
# differential_evolution step 604: f(x)= 3.7750272461778804
# differential_evolution step 605: f(x)= 3.7750272461778804
# differential_evolution step 606: f(x)= 3.7710131934285065
# differential_evolution step 607: f(x)= 3.7710131934285065
# differential_evolution step 608: f(x)= 3.7710131934285065
# differential_evolution step 609: f(x)= 3.7710131934285065
# differential_evolution step 610: f(x)= 3.7710131934285065
# differential_evolution step 611: f(x)= 3.763605092948292
# differential_evolution step 612: f(x)= 3.7563871331838685
# differential_evolution step 613: f(x)= 3.7563871331838685
# differential_evolution step 614: f(x)= 3.7563871331838685
# differential_evolution step 615: f(x)= 3.752809354190397
# differential_evolution step 616: f(x)= 3.7485897269187403
# differential_evolution step 617: f(x)= 3.7485897269187403
# differential_evolution step 618: f(x)= 3.7485897269187403
# differential_evolution step 619: f(x)= 3.7485897269187403
# differential_evolution step 620: f(x)= 3.7485897269187403
# differential_evolution step 621: f(x)= 3.7485897269187403
# differential_evolution step 622: f(x)= 3.745107909593361
# differential_evolution step 623: f(x)= 3.745107909593361
# differential_evolution step 624: f(x)= 3.745107909593361
# differential_evolution step 625: f(x)= 3.745107909593361
# differential_evolution step 626: f(x)= 3.745107909593361
# differential_evolution step 627: f(x)= 3.7449277221436374
# differential_evolution step 628: f(x)= 3.7449277221436374
# differential_evolution step 629: f(x)= 3.7449277221436374
# differential_evolution step 630: f(x)= 3.7449277221436374
# differential_evolution step 631: f(x)= 3.7449277221436374
# differential_evolution step 632: f(x)= 3.7449277221436374
# differential_evolution step 633: f(x)= 3.7449277221436374
# differential_evolution step 634: f(x)= 3.7449277221436374
# differential_evolution step 635: f(x)= 3.7449277221436374
# differential_evolution step 636: f(x)= 3.7405581229668057
# differential_evolution step 637: f(x)= 3.7405581229668057
# differential_evolution step 638: f(x)= 3.7405581229668057
# differential_evolution step 639: f(x)= 3.7405581229668057
# differential_evolution step 640: f(x)= 3.7405581229668057
# differential_evolution step 641: f(x)= 3.7405581229668057
# differential_evolution step 642: f(x)= 3.7405581229668057
# differential_evolution step 643: f(x)= 3.7405581229668057
# differential_evolution step 644: f(x)= 3.7405581229668057
# differential_evolution step 645: f(x)= 3.74026603881121
# differential_evolution step 646: f(x)= 3.74026603881121
# differential_evolution step 647: f(x)= 3.74026603881121
# differential_evolution step 648: f(x)= 3.74026603881121
# differential_evolution step 649: f(x)= 3.74026603881121
# differential_evolution step 650: f(x)= 3.74026603881121
# differential_evolution step 651: f(x)= 3.74026603881121
# differential_evolution step 652: f(x)= 3.74026603881121
# differential_evolution step 653: f(x)= 3.7375064832058458
# differential_evolution step 654: f(x)= 3.7375064832058458
# differential_evolution step 655: f(x)= 3.7347057471750964
# differential_evolution step 656: f(x)= 3.7347057471750964
# differential_evolution step 657: f(x)= 3.73278616575674
# differential_evolution step 658: f(x)= 3.73278616575674
# differential_evolution step 659: f(x)= 3.73278616575674
# differential_evolution step 660: f(x)= 3.731192754450982
# differential_evolution step 661: f(x)= 3.731192754450982
# differential_evolution step 662: f(x)= 3.731192754450982
# differential_evolution step 663: f(x)= 3.7253728355637703
# differential_evolution step 664: f(x)= 3.7253728355637703
# differential_evolution step 665: f(x)= 3.7253728355637703
# differential_evolution step 666: f(x)= 3.7253728355637703
# differential_evolution step 667: f(x)= 3.7253728355637703
# differential_evolution step 668: f(x)= 3.7253728355637703
# differential_evolution step 669: f(x)= 3.7253728355637703
# differential_evolution step 670: f(x)= 3.7253728355637703
# differential_evolution step 671: f(x)= 3.7253728355637703
# differential_evolution step 672: f(x)= 3.7253728355637703
# differential_evolution step 673: f(x)= 3.7253728355637703
# differential_evolution step 674: f(x)= 3.7253728355637703
# differential_evolution step 675: f(x)= 3.7253728355637703
# differential_evolution step 676: f(x)= 3.7253728355637703
# differential_evolution step 677: f(x)= 3.7253728355637703
# differential_evolution step 678: f(x)= 3.7253728355637703
# differential_evolution step 679: f(x)= 3.7253728355637703
# differential_evolution step 680: f(x)= 3.7253728355637703
# differential_evolution step 681: f(x)= 3.7253728355637703
# differential_evolution step 682: f(x)= 3.7253728355637703
# differential_evolution step 683: f(x)= 3.7253728355637703
# differential_evolution step 684: f(x)= 3.7253728355637703
# differential_evolution step 685: f(x)= 3.7253728355637703
# differential_evolution step 686: f(x)= 3.7253728355637703
# differential_evolution step 687: f(x)= 3.7253728355637703
# differential_evolution step 688: f(x)= 3.7253086472364374
# differential_evolution step 689: f(x)= 3.7253086472364374
# differential_evolution step 690: f(x)= 3.7253086472364374
# differential_evolution step 691: f(x)= 3.7253086472364374
# differential_evolution step 692: f(x)= 3.7253086472364374
# differential_evolution step 693: f(x)= 3.7253086472364374
# differential_evolution step 694: f(x)= 3.7253086472364374
# differential_evolution step 695: f(x)= 3.7253086472364374
# differential_evolution step 696: f(x)= 3.7244674873508696
# differential_evolution step 697: f(x)= 3.7244674873508696
# differential_evolution step 698: f(x)= 3.7244674873508696
# differential_evolution step 699: f(x)= 3.7223829342184596
# differential_evolution step 700: f(x)= 3.7223829342184596
# differential_evolution step 701: f(x)= 3.7223829342184596
# differential_evolution step 702: f(x)= 3.7223829342184596
# differential_evolution step 703: f(x)= 3.7223829342184596
# differential_evolution step 704: f(x)= 3.7223829342184596
# differential_evolution step 705: f(x)= 3.7223829342184596
# differential_evolution step 706: f(x)= 3.7223829342184596
# differential_evolution step 707: f(x)= 3.721515224920719
# differential_evolution step 708: f(x)= 3.720893398094581
# differential_evolution step 709: f(x)= 3.720893398094581
# differential_evolution step 710: f(x)= 3.720893398094581
# differential_evolution step 711: f(x)= 3.720893398094581
# differential_evolution step 712: f(x)= 3.720893398094581
# differential_evolution step 713: f(x)= 3.720893398094581
# differential_evolution step 714: f(x)= 3.720893398094581
# differential_evolution step 715: f(x)= 3.720893398094581
# differential_evolution step 716: f(x)= 3.720893398094581
# differential_evolution step 717: f(x)= 3.720893398094581
# differential_evolution step 718: f(x)= 3.720893398094581
# differential_evolution step 719: f(x)= 3.720893398094581
# differential_evolution step 720: f(x)= 3.720893398094581
# differential_evolution step 721: f(x)= 3.720893398094581
# differential_evolution step 722: f(x)= 3.720893398094581
# differential_evolution step 723: f(x)= 3.720893398094581
# differential_evolution step 724: f(x)= 3.720893398094581
# differential_evolution step 725: f(x)= 3.720893398094581
# differential_evolution step 726: f(x)= 3.720893398094581
# differential_evolution step 727: f(x)= 3.720893398094581
# differential_evolution step 728: f(x)= 3.720893398094581
# differential_evolution step 729: f(x)= 3.7198556014548214
# differential_evolution step 730: f(x)= 3.7198556014548214
# differential_evolution step 731: f(x)= 3.7198556014548214
# differential_evolution step 732: f(x)= 3.7198556014548214
# differential_evolution step 733: f(x)= 3.7194063055304327
# differential_evolution step 734: f(x)= 3.7191697861277366
# differential_evolution step 735: f(x)= 3.7191697861277366
# differential_evolution step 736: f(x)= 3.7191697861277366
# differential_evolution step 737: f(x)= 3.7191697861277366
# differential_evolution step 738: f(x)= 3.7191697861277366
# differential_evolution step 739: f(x)= 3.7191697861277366
# differential_evolution step 740: f(x)= 3.7191697861277366
# differential_evolution step 741: f(x)= 3.7191697861277366
# differential_evolution step 742: f(x)= 3.7191697861277366
# differential_evolution step 743: f(x)= 3.7191697861277366
# differential_evolution step 744: f(x)= 3.7191697861277366
# differential_evolution step 745: f(x)= 3.7191697861277366
# differential_evolution step 746: f(x)= 3.7191697861277366
# differential_evolution step 747: f(x)= 3.7191697861277366
# differential_evolution step 748: f(x)= 3.7191697861277366
# differential_evolution step 749: f(x)= 3.7191697861277366
# differential_evolution step 750: f(x)= 3.7191697861277366
# differential_evolution step 751: f(x)= 3.7191697861277366
# differential_evolution step 752: f(x)= 3.7190784203287945
# differential_evolution step 753: f(x)= 3.7190784203287945
# differential_evolution step 754: f(x)= 3.7190784203287945
# differential_evolution step 755: f(x)= 3.7188631359237587
# differential_evolution step 756: f(x)= 3.7188631359237587
# differential_evolution step 757: f(x)= 3.7188631359237587
# differential_evolution step 758: f(x)= 3.71860821606021
# differential_evolution step 759: f(x)= 3.718551088577664
# differential_evolution step 760: f(x)= 3.718551088577664
# differential_evolution step 761: f(x)= 3.7185428869316617
# differential_evolution step 762: f(x)= 3.7185428869316617
# differential_evolution step 763: f(x)= 3.7185428869316617
# differential_evolution step 764: f(x)= 3.7185428869316617
# differential_evolution step 765: f(x)= 3.7185428869316617
# differential_evolution step 766: f(x)= 3.7185428869316617
# differential_evolution step 767: f(x)= 3.7185428869316617
# differential_evolution step 768: f(x)= 3.7185428869316617
# differential_evolution step 769: f(x)= 3.7183787438455336
# differential_evolution step 770: f(x)= 3.7183787438455336
# differential_evolution step 771: f(x)= 3.7180963921775976
# differential_evolution step 772: f(x)= 3.7180963921775976
# differential_evolution step 773: f(x)= 3.7180963921775976
# differential_evolution step 774: f(x)= 3.7180963921775976
# differential_evolution step 775: f(x)= 3.7180963921775976
# differential_evolution step 776: f(x)= 3.7180963921775976
# differential_evolution step 777: f(x)= 3.7180963921775976
# differential_evolution step 778: f(x)= 3.7180963921775976
# differential_evolution step 779: f(x)= 3.7180963921775976
# differential_evolution step 780: f(x)= 3.7179137540331584
# differential_evolution step 781: f(x)= 3.7179137540331584
# differential_evolution step 782: f(x)= 3.7179137540331584
# differential_evolution step 783: f(x)= 3.7179137540331584
# differential_evolution step 784: f(x)= 3.7179137540331584
# differential_evolution step 785: f(x)= 3.7179137540331584
# differential_evolution step 786: f(x)= 3.7179137540331584
# differential_evolution step 787: f(x)= 3.7179137540331584
# differential_evolution step 788: f(x)= 3.7179137540331584
# differential_evolution step 789: f(x)= 3.7179137540331584
# differential_evolution step 790: f(x)= 3.7179137540331584
# differential_evolution step 791: f(x)= 3.7179137540331584
# differential_evolution step 792: f(x)= 3.7179137540331584
# differential_evolution step 793: f(x)= 3.7179137540331584
# differential_evolution step 794: f(x)= 3.7179137540331584
# differential_evolution step 795: f(x)= 3.7179137540331584
# differential_evolution step 796: f(x)= 3.7179137540331584
# differential_evolution step 797: f(x)= 3.7179137540331584
# differential_evolution step 798: f(x)= 3.717870850744265
# differential_evolution step 799: f(x)= 3.717870850744265
# differential_evolution step 800: f(x)= 3.717870850744265
# differential_evolution step 801: f(x)= 3.717870850744265
# differential_evolution step 802: f(x)= 3.717870850744265
# differential_evolution step 803: f(x)= 3.717870850744265
# differential_evolution step 804: f(x)= 3.7177983313626277
# differential_evolution step 805: f(x)= 3.7177983313626277
# differential_evolution step 806: f(x)= 3.7177983313626277
# differential_evolution step 807: f(x)= 3.7177983313626277
# differential_evolution step 808: f(x)= 3.7177983313626277
# differential_evolution step 809: f(x)= 3.7177983313626277
# differential_evolution step 810: f(x)= 3.7176795996427443
# differential_evolution step 811: f(x)= 3.7176795996427443
# differential_evolution step 812: f(x)= 3.7176795996427443
# differential_evolution step 813: f(x)= 3.7176795996427443
# differential_evolution step 814: f(x)= 3.7176795996427443
# differential_evolution step 815: f(x)= 3.7176795996427443
# differential_evolution step 816: f(x)= 3.7176795996427443
# differential_evolution step 817: f(x)= 3.7176795996427443
# differential_evolution step 818: f(x)= 3.7176795996427443
# differential_evolution step 819: f(x)= 3.7176795996427443
# differential_evolution step 820: f(x)= 3.7176795996427443
# differential_evolution step 821: f(x)= 3.7176795996427443
# differential_evolution step 822: f(x)= 3.7176795996427443
# differential_evolution step 823: f(x)= 3.7176795996427443
# differential_evolution step 824: f(x)= 3.7176795996427443
# differential_evolution step 825: f(x)= 3.7176795996427443
# differential_evolution step 826: f(x)= 3.7176795996427443
# differential_evolution step 827: f(x)= 3.7176795996427443
# differential_evolution step 828: f(x)= 3.7176795996427443
# differential_evolution step 829: f(x)= 3.7176795996427443
# differential_evolution step 830: f(x)= 3.7176795996427443
# differential_evolution step 831: f(x)= 3.7176795996427443
# differential_evolution step 832: f(x)= 3.7176795996427443
# differential_evolution step 833: f(x)= 3.7176795996427443
# differential_evolution step 834: f(x)= 3.7176795996427443
# differential_evolution step 835: f(x)= 3.7176795996427443
# differential_evolution step 836: f(x)= 3.7176795996427443
# differential_evolution step 837: f(x)= 3.7176795996427443
# differential_evolution step 838: f(x)= 3.7176795996427443
# differential_evolution step 839: f(x)= 3.7176795996427443
# differential_evolution step 840: f(x)= 3.7176795996427443
# differential_evolution step 841: f(x)= 3.7176795996427443
# differential_evolution step 842: f(x)= 3.7176795996427443
# differential_evolution step 843: f(x)= 3.7176795996427443
# differential_evolution step 844: f(x)= 3.7176795996427443
# differential_evolution step 845: f(x)= 3.7176752993864577
# differential_evolution step 846: f(x)= 3.7176752993864577
# differential_evolution step 847: f(x)= 3.7176190889888416
# differential_evolution step 848: f(x)= 3.7176190889888416
# differential_evolution step 849: f(x)= 3.717604222107298
# differential_evolution step 850: f(x)= 3.717604222107298
# differential_evolution step 851: f(x)= 3.717604222107298
# differential_evolution step 852: f(x)= 3.717604222107298
# differential_evolution step 853: f(x)= 3.717604222107298
# differential_evolution step 854: f(x)= 3.717604222107298
# differential_evolution step 855: f(x)= 3.717604222107298
# differential_evolution step 856: f(x)= 3.717604222107298
# differential_evolution step 857: f(x)= 3.717604222107298
# differential_evolution step 858: f(x)= 3.717604222107298
# differential_evolution step 859: f(x)= 3.717590364892434
# differential_evolution step 860: f(x)= 3.717590364892434
# differential_evolution step 861: f(x)= 3.717590364892434
# differential_evolution step 862: f(x)= 3.717590364892434
# differential_evolution step 863: f(x)= 3.717590364892434
# differential_evolution step 864: f(x)= 3.717590364892434
# differential_evolution step 865: f(x)= 3.717590364892434
# differential_evolution step 866: f(x)= 3.717590364892434
# differential_evolution step 867: f(x)= 3.717590364892434
# differential_evolution step 868: f(x)= 3.717590364892434
# differential_evolution step 869: f(x)= 3.717590364892434
# differential_evolution step 870: f(x)= 3.717561867356005
# differential_evolution step 871: f(x)= 3.717561867356005
# differential_evolution step 872: f(x)= 3.7175460596980936
# differential_evolution step 873: f(x)= 3.7175460596980936
# differential_evolution step 874: f(x)= 3.7175460596980936
# differential_evolution step 875: f(x)= 3.7175460596980936
# differential_evolution step 876: f(x)= 3.7175460596980936
# differential_evolution step 877: f(x)= 3.7175460596980936
# differential_evolution step 878: f(x)= 3.717545210507781
# differential_evolution step 879: f(x)= 3.717545210507781
# differential_evolution step 880: f(x)= 3.717545210507781
# differential_evolution step 881: f(x)= 3.717545210507781
# differential_evolution step 882: f(x)= 3.717545210507781
# differential_evolution step 883: f(x)= 3.7175420217260666
# differential_evolution step 884: f(x)= 3.7175420217260666
# differential_evolution step 885: f(x)= 3.7175420217260666
# differential_evolution step 886: f(x)= 3.717541013585446
# differential_evolution step 887: f(x)= 3.717541013585446
# differential_evolution step 888: f(x)= 3.717532451500867
# differential_evolution step 889: f(x)= 3.717532451500867
# differential_evolution step 890: f(x)= 3.717532451500867
# differential_evolution step 891: f(x)= 3.717532451500867
# differential_evolution step 892: f(x)= 3.717532451500867
# differential_evolution step 893: f(x)= 3.717532451500867
# differential_evolution step 894: f(x)= 3.717532451500867
# differential_evolution step 895: f(x)= 3.717532451500867
# differential_evolution step 896: f(x)= 3.717532451500867
# differential_evolution step 897: f(x)= 3.717532451500867
# differential_evolution step 898: f(x)= 3.717532451500867
# differential_evolution step 899: f(x)= 3.717532451500867
# differential_evolution step 900: f(x)= 3.717532451500867
# differential_evolution step 901: f(x)= 3.717530225569083
# differential_evolution step 902: f(x)= 3.717530225569083
# differential_evolution step 903: f(x)= 3.717522272937551
# differential_evolution step 904: f(x)= 3.717515536558751
# differential_evolution step 905: f(x)= 3.717515536558751
# differential_evolution step 906: f(x)= 3.717515536558751
# differential_evolution step 907: f(x)= 3.717515536558751
# differential_evolution step 908: f(x)= 3.717515536558751
# differential_evolution step 909: f(x)= 3.717515536558751
# differential_evolution step 910: f(x)= 3.717515428784488
# differential_evolution step 911: f(x)= 3.717515428784488
# differential_evolution step 912: f(x)= 3.717515428784488
# differential_evolution step 913: f(x)= 3.717515428784488
# differential_evolution step 914: f(x)= 3.717515428784488
# differential_evolution step 915: f(x)= 3.717515428784488
# differential_evolution step 916: f(x)= 3.717515428784488
# differential_evolution step 917: f(x)= 3.717515428784488
# differential_evolution step 918: f(x)= 3.717511098490886
# differential_evolution step 919: f(x)= 3.717507977265858
# differential_evolution step 920: f(x)= 3.717507977265858
# differential_evolution step 921: f(x)= 3.717507977265858
# differential_evolution step 922: f(x)= 3.717507977265858
# differential_evolution step 923: f(x)= 3.717507977265858
# differential_evolution step 924: f(x)= 3.717507977265858
# differential_evolution step 925: f(x)= 3.717507977265858
# differential_evolution step 926: f(x)= 3.717507977265858
# differential_evolution step 927: f(x)= 3.717507977265858
# differential_evolution step 928: f(x)= 3.7175076259167272
# differential_evolution step 929: f(x)= 3.7175076259167272
# differential_evolution step 930: f(x)= 3.7175076259167272
# differential_evolution step 931: f(x)= 3.7175076259167272
# differential_evolution step 932: f(x)= 3.7175076259167272
# differential_evolution step 933: f(x)= 3.717505710732168
# differential_evolution step 934: f(x)= 3.717505710732168
# differential_evolution step 935: f(x)= 3.717505710732168
# differential_evolution step 936: f(x)= 3.717505710732168
# differential_evolution step 937: f(x)= 3.717505710732168
# differential_evolution step 938: f(x)= 3.717504844405238
# differential_evolution step 939: f(x)= 3.717504844405238
# differential_evolution step 940: f(x)= 3.717504844405238
# differential_evolution step 941: f(x)= 3.717504844405238
# differential_evolution step 942: f(x)= 3.717504844405238
# differential_evolution step 943: f(x)= 3.717504844405238
# differential_evolution step 944: f(x)= 3.717504844405238
# differential_evolution step 945: f(x)= 3.7175037532720685
# differential_evolution step 946: f(x)= 3.7175037532720685
# differential_evolution step 947: f(x)= 3.7175037532720685
# differential_evolution step 948: f(x)= 3.7175037532720685
# differential_evolution step 949: f(x)= 3.7175037532720685
# differential_evolution step 950: f(x)= 3.7175037532720685
# differential_evolution step 951: f(x)= 3.7175037532720685
# differential_evolution step 952: f(x)= 3.7175037532720685
# differential_evolution step 953: f(x)= 3.7175037532720685
# differential_evolution step 954: f(x)= 3.7175029961520645
# differential_evolution step 955: f(x)= 3.7175029961520645
# differential_evolution step 956: f(x)= 3.7175029961520645
# differential_evolution step 957: f(x)= 3.7175029961520645
# differential_evolution step 958: f(x)= 3.7175029961520645
# differential_evolution step 959: f(x)= 3.7175029961520645
# differential_evolution step 960: f(x)= 3.7175029961520645
# differential_evolution step 961: f(x)= 3.7175012307992104
# differential_evolution step 962: f(x)= 3.7175012307992104
# differential_evolution step 963: f(x)= 3.7175012307992104
# differential_evolution step 964: f(x)= 3.7175012307992104
# differential_evolution step 965: f(x)= 3.7175012307992104
# differential_evolution step 966: f(x)= 3.7175012307992104
# differential_evolution step 967: f(x)= 3.7175012307992104
# differential_evolution step 968: f(x)= 3.7175012307992104
# differential_evolution step 969: f(x)= 3.7175012307992104
# differential_evolution step 970: f(x)= 3.7175012307992104
# differential_evolution step 971: f(x)= 3.7175012307992104
# differential_evolution step 972: f(x)= 3.7175012307992104
# differential_evolution step 973: f(x)= 3.7175012307992104
# differential_evolution step 974: f(x)= 3.7175012307992104
# differential_evolution step 975: f(x)= 3.7175012307992104
# differential_evolution step 976: f(x)= 3.7175012307992104
# differential_evolution step 977: f(x)= 3.7175012307992104
# differential_evolution step 978: f(x)= 3.7175012307992104
# differential_evolution step 979: f(x)= 3.7175012307992104
# differential_evolution step 980: f(x)= 3.7175012307992104
# differential_evolution step 981: f(x)= 3.7175012307992104
# differential_evolution step 982: f(x)= 3.7175012307992104
# differential_evolution step 983: f(x)= 3.7175012307992104
# differential_evolution step 984: f(x)= 3.717498260285666
# differential_evolution step 985: f(x)= 3.717498260285666
# differential_evolution step 986: f(x)= 3.717498260285666
# differential_evolution step 987: f(x)= 3.717498260285666
# differential_evolution step 988: f(x)= 3.717498260285666
# differential_evolution step 989: f(x)= 3.717498260285666
# differential_evolution step 990: f(x)= 3.717498260285666
# differential_evolution step 991: f(x)= 3.717498260285666
# differential_evolution step 992: f(x)= 3.717498260285666
# differential_evolution step 993: f(x)= 3.7174947361010577
# differential_evolution step 994: f(x)= 3.7174947361010577
# differential_evolution step 995: f(x)= 3.7174947361010577
# differential_evolution step 996: f(x)= 3.7174947361010577
# differential_evolution step 997: f(x)= 3.7174947361010577
# differential_evolution step 998: f(x)= 3.7174947361010577
# differential_evolution step 999: f(x)= 3.7174947361010577
# differential_evolution step 1000: f(x)= 3.717493646308123
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=8.0373, r_e=2.8241, n=0.6114, x_0=40.1425
# Sérsic 2: I_e=0.3863, r_e=22.8569, n=1.6268, x_0=49.1105
# Sérsic 3: I_e=0.7469, r_e=4.2487, n=1.4394, x_0=58.8126
# Chi quadro minimo: 3.717490418903317
# False

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = radial_profile_error_OIII)#, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, radial_profile_error_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=7.7384, r_e=2.8967, n=0.6400, x_0=40.1843
# Sérsic 2: I_e=0.3298, r_e=24.5676, n=1.7286, x_0=49.1578
# Sérsic 3: I_e=0.7845, r_e=4.3351, n=1.3881, x_0=58.8266
# [0.29958667 0.07115264 0.02969567 0.02587291 0.06413342 2.6727182
#  0.13441701 0.10665299 0.2141914  0.87913999 0.20648619 0.05907532]
# 7.719364773084542

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 24404.273621630222
# differential_evolution step 2: f(x)= 19524.364077860613
# differential_evolution step 3: f(x)= 19524.364077860613
# differential_evolution step 4: f(x)= 19524.364077860613
# differential_evolution step 5: f(x)= 19524.364077860613
# differential_evolution step 6: f(x)= 19524.364077860613
# differential_evolution step 7: f(x)= 19524.364077860613
# differential_evolution step 8: f(x)= 19524.364077860613
# differential_evolution step 9: f(x)= 17197.92008714751
# differential_evolution step 10: f(x)= 17197.92008714751
# differential_evolution step 11: f(x)= 17197.92008714751
# differential_evolution step 12: f(x)= 16881.2086832146
# differential_evolution step 13: f(x)= 16815.242425415603
# differential_evolution step 14: f(x)= 14699.85666043054
# differential_evolution step 15: f(x)= 14550.58107275623
# differential_evolution step 16: f(x)= 14550.58107275623
# differential_evolution step 17: f(x)= 14550.58107275623
# differential_evolution step 18: f(x)= 12711.963517113725
# differential_evolution step 19: f(x)= 12711.963517113725
# differential_evolution step 20: f(x)= 12343.025392046842
# differential_evolution step 21: f(x)= 12195.038539352743
# differential_evolution step 22: f(x)= 10630.142508122723
# differential_evolution step 23: f(x)= 9679.84905445203
# differential_evolution step 24: f(x)= 9679.84905445203
# differential_evolution step 25: f(x)= 9679.84905445203
# differential_evolution step 26: f(x)= 9679.84905445203
# differential_evolution step 27: f(x)= 9679.84905445203
# differential_evolution step 28: f(x)= 9679.84905445203
# differential_evolution step 29: f(x)= 9679.84905445203
# differential_evolution step 30: f(x)= 9679.84905445203
# differential_evolution step 31: f(x)= 9679.84905445203
# differential_evolution step 32: f(x)= 9679.84905445203
# differential_evolution step 33: f(x)= 9679.84905445203
# differential_evolution step 34: f(x)= 9679.84905445203
# differential_evolution step 35: f(x)= 9679.84905445203
# differential_evolution step 36: f(x)= 9679.84905445203
# differential_evolution step 37: f(x)= 9587.436802002016
# differential_evolution step 38: f(x)= 9587.436802002016
# differential_evolution step 39: f(x)= 9587.436802002016
# differential_evolution step 40: f(x)= 9100.459538545429
# differential_evolution step 41: f(x)= 8972.206115353638
# differential_evolution step 42: f(x)= 8972.206115353638
# differential_evolution step 43: f(x)= 8889.821349079153
# differential_evolution step 44: f(x)= 8889.821349079153
# differential_evolution step 45: f(x)= 8889.821349079153
# differential_evolution step 46: f(x)= 8889.821349079153
# differential_evolution step 47: f(x)= 8889.821349079153
# differential_evolution step 48: f(x)= 8346.374165923266
# differential_evolution step 49: f(x)= 8346.374165923266
# differential_evolution step 50: f(x)= 8346.374165923266
# differential_evolution step 51: f(x)= 8346.374165923266
# differential_evolution step 52: f(x)= 8346.374165923266
# differential_evolution step 53: f(x)= 8346.374165923266
# differential_evolution step 54: f(x)= 8346.374165923266
# differential_evolution step 55: f(x)= 8346.374165923266
# differential_evolution step 56: f(x)= 8306.253068199525
# differential_evolution step 57: f(x)= 8306.253068199525
# differential_evolution step 58: f(x)= 8306.253068199525
# differential_evolution step 59: f(x)= 8233.330004898453
# differential_evolution step 60: f(x)= 8233.330004898453
# differential_evolution step 61: f(x)= 8216.806404859106
# differential_evolution step 62: f(x)= 8216.806404859106
# differential_evolution step 63: f(x)= 8216.806404859106
# differential_evolution step 64: f(x)= 8158.553935627891
# differential_evolution step 65: f(x)= 8139.361282635443
# differential_evolution step 66: f(x)= 8139.361282635443
# differential_evolution step 67: f(x)= 8139.361282635443
# differential_evolution step 68: f(x)= 8090.113297052226
# differential_evolution step 69: f(x)= 7925.721418320447
# differential_evolution step 70: f(x)= 7925.721418320447
# differential_evolution step 71: f(x)= 7925.721418320447
# differential_evolution step 72: f(x)= 7784.23231694607
# differential_evolution step 73: f(x)= 7358.5237239427515
# differential_evolution step 74: f(x)= 7358.5237239427515
# differential_evolution step 75: f(x)= 7175.9951755551965
# differential_evolution step 76: f(x)= 6730.975347063664
# differential_evolution step 77: f(x)= 6730.975347063664
# differential_evolution step 78: f(x)= 6730.975347063664
# differential_evolution step 79: f(x)= 6635.772657308048
# differential_evolution step 80: f(x)= 6635.772657308048
# differential_evolution step 81: f(x)= 6635.772657308048
# differential_evolution step 82: f(x)= 6635.772657308048
# differential_evolution step 83: f(x)= 6510.628722277499
# differential_evolution step 84: f(x)= 6510.628722277499
# differential_evolution step 85: f(x)= 6510.628722277499
# differential_evolution step 86: f(x)= 6510.628722277499
# differential_evolution step 87: f(x)= 6510.628722277499
# differential_evolution step 88: f(x)= 6510.628722277499
# differential_evolution step 89: f(x)= 6510.628722277499
# differential_evolution step 90: f(x)= 6510.628722277499
# differential_evolution step 91: f(x)= 6510.628722277499
# differential_evolution step 92: f(x)= 6510.628722277499
# differential_evolution step 93: f(x)= 6451.820068849677
# differential_evolution step 94: f(x)= 6451.820068849677
# differential_evolution step 95: f(x)= 6451.820068849677
# differential_evolution step 96: f(x)= 6451.820068849677
# differential_evolution step 97: f(x)= 6451.820068849677
# differential_evolution step 98: f(x)= 6362.375182743615
# differential_evolution step 99: f(x)= 6362.375182743615
# differential_evolution step 100: f(x)= 6362.375182743615
# differential_evolution step 101: f(x)= 6268.816275182784
# differential_evolution step 102: f(x)= 6268.816275182784
# differential_evolution step 103: f(x)= 6268.816275182784
# differential_evolution step 104: f(x)= 6268.816275182784
# differential_evolution step 105: f(x)= 6268.816275182784
# differential_evolution step 106: f(x)= 6196.294667683133
# differential_evolution step 107: f(x)= 6196.294667683133
# differential_evolution step 108: f(x)= 6196.294667683133
# differential_evolution step 109: f(x)= 6196.294667683133
# differential_evolution step 110: f(x)= 6187.867876418185
# differential_evolution step 111: f(x)= 6167.222649477865
# differential_evolution step 112: f(x)= 6167.222649477865
# differential_evolution step 113: f(x)= 6167.222649477865
# differential_evolution step 114: f(x)= 6167.222649477865
# differential_evolution step 115: f(x)= 6167.222649477865
# differential_evolution step 116: f(x)= 6167.222649477865
# differential_evolution step 117: f(x)= 6167.222649477865
# differential_evolution step 118: f(x)= 6167.222649477865
# differential_evolution step 119: f(x)= 6167.222649477865
# differential_evolution step 120: f(x)= 6167.222649477865
# differential_evolution step 121: f(x)= 6167.222649477865
# differential_evolution step 122: f(x)= 6131.4198245112
# differential_evolution step 123: f(x)= 6131.4198245112
# differential_evolution step 124: f(x)= 6131.4198245112
# differential_evolution step 125: f(x)= 6130.53176801723
# differential_evolution step 126: f(x)= 6130.53176801723
# differential_evolution step 127: f(x)= 6130.53176801723
# differential_evolution step 128: f(x)= 6130.53176801723
# differential_evolution step 129: f(x)= 6130.53176801723
# differential_evolution step 130: f(x)= 6130.53176801723
# differential_evolution step 131: f(x)= 6130.53176801723
# differential_evolution step 132: f(x)= 6130.53176801723
# differential_evolution step 133: f(x)= 6130.53176801723
# differential_evolution step 134: f(x)= 6130.53176801723
# differential_evolution step 135: f(x)= 6115.459911041761
# differential_evolution step 136: f(x)= 6096.772100138386
# differential_evolution step 137: f(x)= 6096.772100138386
# differential_evolution step 138: f(x)= 6096.772100138386
# differential_evolution step 139: f(x)= 6096.772100138386
# differential_evolution step 140: f(x)= 6096.772100138386
# differential_evolution step 141: f(x)= 6094.934697365375
# differential_evolution step 142: f(x)= 6094.934697365375
# differential_evolution step 143: f(x)= 6094.934697365375
# differential_evolution step 144: f(x)= 6094.934697365375
# differential_evolution step 145: f(x)= 6094.934697365375
# differential_evolution step 146: f(x)= 6078.083256335852
# differential_evolution step 147: f(x)= 6078.083256335852
# differential_evolution step 148: f(x)= 6051.746935913558
# differential_evolution step 149: f(x)= 6051.746935913558
# differential_evolution step 150: f(x)= 6051.746935913558
# differential_evolution step 151: f(x)= 6051.746935913558
# differential_evolution step 152: f(x)= 6051.746935913558
# differential_evolution step 153: f(x)= 6051.746935913558
# differential_evolution step 154: f(x)= 6049.760023082071
# differential_evolution step 155: f(x)= 6049.760023082071
# differential_evolution step 156: f(x)= 6049.229911713518
# differential_evolution step 157: f(x)= 6049.229911713518
# differential_evolution step 158: f(x)= 6049.229911713518
# differential_evolution step 159: f(x)= 6049.229911713518
# differential_evolution step 160: f(x)= 6049.229911713518
# differential_evolution step 161: f(x)= 6049.229911713518
# differential_evolution step 162: f(x)= 6043.245683077944
# differential_evolution step 163: f(x)= 6043.245683077944
# differential_evolution step 164: f(x)= 6043.245683077944
# differential_evolution step 165: f(x)= 6040.032906247388
# differential_evolution step 166: f(x)= 6040.032906247388
# differential_evolution step 167: f(x)= 6040.032906247388
# differential_evolution step 168: f(x)= 6040.032906247388
# differential_evolution step 169: f(x)= 6040.032906247388
# differential_evolution step 170: f(x)= 6040.032906247388
# differential_evolution step 171: f(x)= 6040.032906247388
# differential_evolution step 172: f(x)= 6040.032906247388
# differential_evolution step 173: f(x)= 6029.369338968984
# differential_evolution step 174: f(x)= 6029.369338968984
# differential_evolution step 175: f(x)= 6029.369338968984
# differential_evolution step 176: f(x)= 6029.369338968984
# differential_evolution step 177: f(x)= 6029.369338968984
# differential_evolution step 178: f(x)= 6024.3652228266565
# differential_evolution step 179: f(x)= 6024.3652228266565
# differential_evolution step 180: f(x)= 6024.3652228266565
# differential_evolution step 181: f(x)= 6023.632518477632
# differential_evolution step 182: f(x)= 6023.632518477632
# differential_evolution step 183: f(x)= 6022.189314905748
# differential_evolution step 184: f(x)= 6022.189314905748
# differential_evolution step 185: f(x)= 6022.189314905748
# differential_evolution step 186: f(x)= 6022.189314905748
# differential_evolution step 187: f(x)= 6022.189314905748
# differential_evolution step 188: f(x)= 6022.189314905748
# differential_evolution step 189: f(x)= 6022.189314905748
# differential_evolution step 190: f(x)= 6017.898387133331
# differential_evolution step 191: f(x)= 6017.898387133331
# differential_evolution step 192: f(x)= 6017.898387133331
# differential_evolution step 193: f(x)= 6017.898387133331
# differential_evolution step 194: f(x)= 6017.898387133331
# differential_evolution step 195: f(x)= 6017.898387133331
# differential_evolution step 196: f(x)= 6017.898387133331
# differential_evolution step 197: f(x)= 6017.898387133331
# differential_evolution step 198: f(x)= 6017.898387133331
# differential_evolution step 199: f(x)= 6017.898387133331
# differential_evolution step 200: f(x)= 6017.898387133331
# differential_evolution step 201: f(x)= 6017.898387133331
# differential_evolution step 202: f(x)= 6017.898387133331
# differential_evolution step 203: f(x)= 6017.898387133331
# differential_evolution step 204: f(x)= 6017.898387133331
# differential_evolution step 205: f(x)= 6017.898387133331
# differential_evolution step 206: f(x)= 6017.898387133331
# differential_evolution step 207: f(x)= 6017.898387133331
# differential_evolution step 208: f(x)= 6017.898387133331
# differential_evolution step 209: f(x)= 6017.898387133331
# differential_evolution step 210: f(x)= 6017.898387133331
# differential_evolution step 211: f(x)= 6017.898387133331
# differential_evolution step 212: f(x)= 6017.063951805258
# differential_evolution step 213: f(x)= 6017.063951805258
# differential_evolution step 214: f(x)= 6017.063951805258
# differential_evolution step 215: f(x)= 6017.063951805258
# differential_evolution step 216: f(x)= 6017.063951805258
# differential_evolution step 217: f(x)= 6017.063951805258
# differential_evolution step 218: f(x)= 6017.063951805258
# differential_evolution step 219: f(x)= 6016.383261406981
# differential_evolution step 220: f(x)= 6016.383261406981
# differential_evolution step 221: f(x)= 6016.383261406981
# differential_evolution step 222: f(x)= 6016.383261406981
# differential_evolution step 223: f(x)= 6016.035337630064
# differential_evolution step 224: f(x)= 6016.035337630064
# differential_evolution step 225: f(x)= 6016.035337630064
# differential_evolution step 226: f(x)= 6016.035337630064
# differential_evolution step 227: f(x)= 6016.03066659412
# differential_evolution step 228: f(x)= 6016.03066659412
# differential_evolution step 229: f(x)= 6016.03066659412
# differential_evolution step 230: f(x)= 6016.03066659412
# differential_evolution step 231: f(x)= 6016.03066659412
# differential_evolution step 232: f(x)= 6016.03066659412
# differential_evolution step 233: f(x)= 6016.03066659412
# differential_evolution step 234: f(x)= 6016.03066659412
# differential_evolution step 235: f(x)= 6016.03066659412
# differential_evolution step 236: f(x)= 6016.03066659412
# differential_evolution step 237: f(x)= 6016.03066659412
# differential_evolution step 238: f(x)= 6015.243525738609
# differential_evolution step 239: f(x)= 6015.243525738609
# differential_evolution step 240: f(x)= 6015.243525738609
# differential_evolution step 241: f(x)= 6015.071892326173
# differential_evolution step 242: f(x)= 6015.071892326173
# differential_evolution step 243: f(x)= 6014.978870930737
# differential_evolution step 244: f(x)= 6014.978870930737
# differential_evolution step 245: f(x)= 6014.978870930737
# differential_evolution step 246: f(x)= 6014.621001811348
# differential_evolution step 247: f(x)= 6014.621001811348
# differential_evolution step 248: f(x)= 6014.621001811348
# differential_evolution step 249: f(x)= 6014.621001811348
# differential_evolution step 250: f(x)= 6014.414039008078
# differential_evolution step 251: f(x)= 6014.291771013238
# differential_evolution step 252: f(x)= 6014.291771013238
# differential_evolution step 253: f(x)= 6014.291771013238
# differential_evolution step 254: f(x)= 6014.291771013238
# differential_evolution step 255: f(x)= 6014.291771013238
# differential_evolution step 256: f(x)= 6014.291771013238
# differential_evolution step 257: f(x)= 6014.291771013238
# differential_evolution step 258: f(x)= 6014.133106949179
# differential_evolution step 259: f(x)= 6014.133106949179
# differential_evolution step 260: f(x)= 6014.133106949179
# differential_evolution step 261: f(x)= 6014.133106949179
# differential_evolution step 262: f(x)= 6014.133106949179
# differential_evolution step 263: f(x)= 6014.133106949179
# differential_evolution step 264: f(x)= 6013.779930256176
# differential_evolution step 265: f(x)= 6013.779930256176
# differential_evolution step 266: f(x)= 6013.745731460488
# differential_evolution step 267: f(x)= 6013.745731460488
# differential_evolution step 268: f(x)= 6013.745731460488
# differential_evolution step 269: f(x)= 6013.745731460488
# differential_evolution step 270: f(x)= 6013.63315570349
# differential_evolution step 271: f(x)= 6013.63315570349
# differential_evolution step 272: f(x)= 6013.63315570349
# differential_evolution step 273: f(x)= 6013.63315570349
# differential_evolution step 274: f(x)= 6013.63315570349
# differential_evolution step 275: f(x)= 6013.566006232102
# differential_evolution step 276: f(x)= 6013.566006232102
# differential_evolution step 277: f(x)= 6013.566006232102
# differential_evolution step 278: f(x)= 6013.566006232102
# differential_evolution step 279: f(x)= 6013.566006232102
# differential_evolution step 280: f(x)= 6013.446773526762
# differential_evolution step 281: f(x)= 6013.446773526762
# differential_evolution step 282: f(x)= 6013.446773526762
# differential_evolution step 283: f(x)= 6013.446773526762
# differential_evolution step 284: f(x)= 6013.446773526762
# differential_evolution step 285: f(x)= 6013.446773526762
# differential_evolution step 286: f(x)= 6013.35449704848
# differential_evolution step 287: f(x)= 6013.35449704848
# differential_evolution step 288: f(x)= 6013.282399437345
# differential_evolution step 289: f(x)= 6013.282399437345
# differential_evolution step 290: f(x)= 6013.282399437345
# differential_evolution step 291: f(x)= 6013.282399437345
# differential_evolution step 292: f(x)= 6013.282399437345
# differential_evolution step 293: f(x)= 6013.282399437345
# differential_evolution step 294: f(x)= 6013.282399437345
# differential_evolution step 295: f(x)= 6013.2472737555145
# differential_evolution step 296: f(x)= 6013.2472737555145
# differential_evolution step 297: f(x)= 6013.2472737555145
# differential_evolution step 298: f(x)= 6013.226175276968
# differential_evolution step 299: f(x)= 6013.226175276968
# differential_evolution step 300: f(x)= 6013.226175276968
# differential_evolution step 301: f(x)= 6013.226175276968
# differential_evolution step 302: f(x)= 6013.212296754772
# differential_evolution step 303: f(x)= 6013.212296754772
# differential_evolution step 304: f(x)= 6013.212296754772
# differential_evolution step 305: f(x)= 6013.127552992781
# differential_evolution step 306: f(x)= 6013.127552992781
# differential_evolution step 307: f(x)= 6013.127552992781
# differential_evolution step 308: f(x)= 6013.127552992781
# differential_evolution step 309: f(x)= 6013.127552992781
# differential_evolution step 310: f(x)= 6013.127552992781
# differential_evolution step 311: f(x)= 6013.127552992781
# differential_evolution step 312: f(x)= 6013.127552992781
# differential_evolution step 313: f(x)= 6013.127552992781
# differential_evolution step 314: f(x)= 6013.127552992781
# differential_evolution step 315: f(x)= 6013.127552992781
# differential_evolution step 316: f(x)= 6013.127552992781
# differential_evolution step 317: f(x)= 6013.127552992781
# differential_evolution step 318: f(x)= 6013.127552992781
# differential_evolution step 319: f(x)= 6013.127552992781
# differential_evolution step 320: f(x)= 6013.127552992781
# differential_evolution step 321: f(x)= 6013.127552992781
# differential_evolution step 322: f(x)= 6013.127552992781
# differential_evolution step 323: f(x)= 6013.119471194821
# differential_evolution step 324: f(x)= 6013.119471194821
# differential_evolution step 325: f(x)= 6013.119471194821
# differential_evolution step 326: f(x)= 6013.107068169686
# differential_evolution step 327: f(x)= 6013.07980435407
# differential_evolution step 328: f(x)= 6013.07980435407
# differential_evolution step 329: f(x)= 6013.07980435407
# differential_evolution step 330: f(x)= 6013.07980435407
# differential_evolution step 331: f(x)= 6013.07980435407
# differential_evolution step 332: f(x)= 6013.07980435407
# differential_evolution step 333: f(x)= 6013.07980435407
# differential_evolution step 334: f(x)= 6013.07980435407
# differential_evolution step 335: f(x)= 6013.07980435407
# differential_evolution step 336: f(x)= 6013.075885232725
# differential_evolution step 337: f(x)= 6013.075885232725
# differential_evolution step 338: f(x)= 6013.075885232725
# differential_evolution step 339: f(x)= 6013.075885232725
# differential_evolution step 340: f(x)= 6013.070336326105
# differential_evolution step 341: f(x)= 6013.070336326105
# differential_evolution step 342: f(x)= 6013.070093037503
# differential_evolution step 343: f(x)= 6013.070093037503
# differential_evolution step 344: f(x)= 6013.070093037503
# differential_evolution step 345: f(x)= 6013.070093037503
# differential_evolution step 346: f(x)= 6013.070093037503
# differential_evolution step 347: f(x)= 6013.070093037503
# differential_evolution step 348: f(x)= 6013.070093037503
# differential_evolution step 349: f(x)= 6013.062159476117
# differential_evolution step 350: f(x)= 6013.047865315003
# differential_evolution step 351: f(x)= 6013.047865315003
# differential_evolution step 352: f(x)= 6013.047865315003
# differential_evolution step 353: f(x)= 6013.047865315003
# differential_evolution step 354: f(x)= 6013.047865315003
# differential_evolution step 355: f(x)= 6013.047865315003
# differential_evolution step 356: f(x)= 6013.045787449403
# differential_evolution step 357: f(x)= 6013.045787449403
# differential_evolution step 358: f(x)= 6013.045787449403
# differential_evolution step 359: f(x)= 6013.045787449403
# differential_evolution step 360: f(x)= 6013.045787449403
# differential_evolution step 361: f(x)= 6013.039907963303
# differential_evolution step 362: f(x)= 6013.039907963303
# differential_evolution step 363: f(x)= 6013.038191587984
# differential_evolution step 364: f(x)= 6013.038191587984
# differential_evolution step 365: f(x)= 6013.038191587984
# differential_evolution step 366: f(x)= 6013.038191587984
# differential_evolution step 367: f(x)= 6013.038191587984
# differential_evolution step 368: f(x)= 6013.035140216854
# differential_evolution step 369: f(x)= 6013.035140216854
# differential_evolution step 370: f(x)= 6013.035140216854
# differential_evolution step 371: f(x)= 6013.035140216854
# differential_evolution step 372: f(x)= 6013.035140216854
# differential_evolution step 373: f(x)= 6013.035140216854
# differential_evolution step 374: f(x)= 6013.035140216854
# differential_evolution step 375: f(x)= 6013.035140216854
# differential_evolution step 376: f(x)= 6013.035140216854
# differential_evolution step 377: f(x)= 6013.035140216854
# differential_evolution step 378: f(x)= 6013.035140216854
# differential_evolution step 379: f(x)= 6013.035140216854
# differential_evolution step 380: f(x)= 6013.0322964478
# differential_evolution step 381: f(x)= 6013.0322964478
# differential_evolution step 382: f(x)= 6013.0322964478
# differential_evolution step 383: f(x)= 6013.0322964478
# differential_evolution step 384: f(x)= 6013.0322964478
# differential_evolution step 385: f(x)= 6013.0322964478
# differential_evolution step 386: f(x)= 6013.0322964478
# differential_evolution step 387: f(x)= 6013.0322964478
# differential_evolution step 388: f(x)= 6013.0322964478
# differential_evolution step 389: f(x)= 6013.030188436737
# differential_evolution step 390: f(x)= 6013.030188436737
# differential_evolution step 391: f(x)= 6013.029869669236
# differential_evolution step 392: f(x)= 6013.029869669236
# differential_evolution step 393: f(x)= 6013.028367254362
# differential_evolution step 394: f(x)= 6013.0265509517685
# differential_evolution step 395: f(x)= 6013.0265509517685
# differential_evolution step 396: f(x)= 6013.0265509517685
# differential_evolution step 397: f(x)= 6013.0265509517685
# differential_evolution step 398: f(x)= 6013.0265509517685
# differential_evolution step 399: f(x)= 6013.02576995801
# differential_evolution step 400: f(x)= 6013.02576995801
# differential_evolution step 401: f(x)= 6013.02576995801
# differential_evolution step 402: f(x)= 6013.02576995801
# differential_evolution step 403: f(x)= 6013.02576995801
# differential_evolution step 404: f(x)= 6013.02576995801
# differential_evolution step 405: f(x)= 6013.02576995801
# differential_evolution step 406: f(x)= 6013.02576995801
# differential_evolution step 407: f(x)= 6013.02576995801
# differential_evolution step 408: f(x)= 6013.02576995801
# differential_evolution step 409: f(x)= 6013.02576995801
# differential_evolution step 410: f(x)= 6013.024126314029
# differential_evolution step 411: f(x)= 6013.024126314029
# differential_evolution step 412: f(x)= 6013.024126314029
# differential_evolution step 413: f(x)= 6013.024126314029
# differential_evolution step 414: f(x)= 6013.024126314029
# differential_evolution step 415: f(x)= 6013.024126314029
# differential_evolution step 416: f(x)= 6013.024126314029
# differential_evolution step 417: f(x)= 6013.023957550926
# differential_evolution step 418: f(x)= 6013.023957550926
# differential_evolution step 419: f(x)= 6013.023957550926
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=10.4034, n=1.8725, x_0=40.4146
# Sérsic 2: I_e=10.0000, r_e=8.3990, n=0.9860, x_0=45.0000
# Sérsic 3: I_e=3.8034, r_e=6.8655, n=2.0151, x_0=59.0091
# Chi quadro minimo: 6013.018733489008
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=9.9999, r_e=9.0700, n=1.9350, x_0=40.4114
# Sérsic 2: I_e=9.9952, r_e=8.5506, n=1.0260, x_0=45.0000
# Sérsic 3: I_e=3.8282, r_e=7.2376, n=1.9886, x_0=58.9940
# [13.39397747 10.75049112  0.90035782  0.16197611 13.63234815 12.35932851
#   0.91899049  1.0949137  10.08628781 11.40286617  3.24207173  0.06566429]
# 541.0010652941555

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 98975.55098583682
# differential_evolution step 2: f(x)= 77305.89626413316
# differential_evolution step 3: f(x)= 63994.75223080503
# differential_evolution step 4: f(x)= 42928.939256211175
# differential_evolution step 5: f(x)= 42928.939256211175
# differential_evolution step 6: f(x)= 35706.07286075847
# differential_evolution step 7: f(x)= 30659.205022910854
# differential_evolution step 8: f(x)= 30659.205022910854
# differential_evolution step 9: f(x)= 30659.205022910854
# differential_evolution step 10: f(x)= 30659.205022910854
# differential_evolution step 11: f(x)= 30659.205022910854
# differential_evolution step 12: f(x)= 30659.205022910854
# differential_evolution step 13: f(x)= 30659.205022910854
# differential_evolution step 14: f(x)= 28836.72469166131
# differential_evolution step 15: f(x)= 28836.72469166131
# differential_evolution step 16: f(x)= 28836.72469166131
# differential_evolution step 17: f(x)= 28836.72469166131
# differential_evolution step 18: f(x)= 28836.72469166131
# differential_evolution step 19: f(x)= 28836.72469166131
# differential_evolution step 20: f(x)= 28836.72469166131
# differential_evolution step 21: f(x)= 28836.72469166131
# differential_evolution step 22: f(x)= 28509.96140468457
# differential_evolution step 23: f(x)= 28509.96140468457
# differential_evolution step 24: f(x)= 28509.96140468457
# differential_evolution step 25: f(x)= 28509.96140468457
# differential_evolution step 26: f(x)= 27454.997693814887
# differential_evolution step 27: f(x)= 27454.997693814887
# differential_evolution step 28: f(x)= 23341.890761376093
# differential_evolution step 29: f(x)= 23341.890761376093
# differential_evolution step 30: f(x)= 23341.890761376093
# differential_evolution step 31: f(x)= 23341.890761376093
# differential_evolution step 32: f(x)= 23341.890761376093
# differential_evolution step 33: f(x)= 23341.890761376093
# differential_evolution step 34: f(x)= 23341.890761376093
# differential_evolution step 35: f(x)= 23341.890761376093
# differential_evolution step 36: f(x)= 23341.890761376093
# differential_evolution step 37: f(x)= 23341.890761376093
# differential_evolution step 38: f(x)= 22587.936100572242
# differential_evolution step 39: f(x)= 22587.936100572242
# differential_evolution step 40: f(x)= 22587.936100572242
# differential_evolution step 41: f(x)= 22587.936100572242
# differential_evolution step 42: f(x)= 22587.936100572242
# differential_evolution step 43: f(x)= 22587.936100572242
# differential_evolution step 44: f(x)= 22506.715510206897
# differential_evolution step 45: f(x)= 22506.715510206897
# differential_evolution step 46: f(x)= 22506.715510206897
# differential_evolution step 47: f(x)= 22506.715510206897
# differential_evolution step 48: f(x)= 22506.715510206897
# differential_evolution step 49: f(x)= 22506.715510206897
# differential_evolution step 50: f(x)= 22506.715510206897
# differential_evolution step 51: f(x)= 22506.715510206897
# differential_evolution step 52: f(x)= 21680.22047043326
# differential_evolution step 53: f(x)= 21680.22047043326
# differential_evolution step 54: f(x)= 21680.22047043326
# differential_evolution step 55: f(x)= 21680.22047043326
# differential_evolution step 56: f(x)= 21680.22047043326
# differential_evolution step 57: f(x)= 21680.22047043326
# differential_evolution step 58: f(x)= 21680.22047043326
# differential_evolution step 59: f(x)= 21569.304250705198
# differential_evolution step 60: f(x)= 21569.304250705198
# differential_evolution step 61: f(x)= 20924.18811878864
# differential_evolution step 62: f(x)= 20924.18811878864
# differential_evolution step 63: f(x)= 20891.729064117488
# differential_evolution step 64: f(x)= 20891.729064117488
# differential_evolution step 65: f(x)= 20838.607590606065
# differential_evolution step 66: f(x)= 20838.607590606065
# differential_evolution step 67: f(x)= 20675.581708210608
# differential_evolution step 68: f(x)= 20675.581708210608
# differential_evolution step 69: f(x)= 20400.001511626437
# differential_evolution step 70: f(x)= 20400.001511626437
# differential_evolution step 71: f(x)= 20400.001511626437
# differential_evolution step 72: f(x)= 20371.74245683598
# differential_evolution step 73: f(x)= 20343.67413504637
# differential_evolution step 74: f(x)= 20244.04455121725
# differential_evolution step 75: f(x)= 20244.04455121725
# differential_evolution step 76: f(x)= 20075.641757146077
# differential_evolution step 77: f(x)= 20075.641757146077
# differential_evolution step 78: f(x)= 20075.641757146077
# differential_evolution step 79: f(x)= 20075.641757146077
# differential_evolution step 80: f(x)= 19581.79534668238
# differential_evolution step 81: f(x)= 19581.79534668238
# differential_evolution step 82: f(x)= 19581.79534668238
# differential_evolution step 83: f(x)= 19581.79534668238
# differential_evolution step 84: f(x)= 19547.56390482259
# differential_evolution step 85: f(x)= 19547.56390482259
# differential_evolution step 86: f(x)= 19547.56390482259
# differential_evolution step 87: f(x)= 19470.33222143049
# differential_evolution step 88: f(x)= 19470.33222143049
# differential_evolution step 89: f(x)= 19470.33222143049
# differential_evolution step 90: f(x)= 19461.85611933786
# differential_evolution step 91: f(x)= 19461.85611933786
# differential_evolution step 92: f(x)= 19461.85611933786
# differential_evolution step 93: f(x)= 19461.85611933786
# differential_evolution step 94: f(x)= 19452.76145611886
# differential_evolution step 95: f(x)= 19403.1057251101
# differential_evolution step 96: f(x)= 19403.1057251101
# differential_evolution step 97: f(x)= 19403.1057251101
# differential_evolution step 98: f(x)= 19290.16475572952
# differential_evolution step 99: f(x)= 19290.16475572952
# differential_evolution step 100: f(x)= 19290.16475572952
# differential_evolution step 101: f(x)= 19290.16475572952
# differential_evolution step 102: f(x)= 19290.16475572952
# differential_evolution step 103: f(x)= 19290.16475572952
# differential_evolution step 104: f(x)= 19290.16475572952
# differential_evolution step 105: f(x)= 19290.16475572952
# differential_evolution step 106: f(x)= 19290.16475572952
# differential_evolution step 107: f(x)= 19290.16475572952
# differential_evolution step 108: f(x)= 19290.16475572952
# differential_evolution step 109: f(x)= 19290.16475572952
# differential_evolution step 110: f(x)= 19290.16475572952
# differential_evolution step 111: f(x)= 19202.293865091262
# differential_evolution step 112: f(x)= 19202.293865091262
# differential_evolution step 113: f(x)= 19202.293865091262
# differential_evolution step 114: f(x)= 19202.293865091262
# differential_evolution step 115: f(x)= 19202.293865091262
# differential_evolution step 116: f(x)= 19202.293865091262
# differential_evolution step 117: f(x)= 19202.293865091262
# differential_evolution step 118: f(x)= 19202.293865091262
# differential_evolution step 119: f(x)= 19202.293865091262
# differential_evolution step 120: f(x)= 19202.293865091262
# differential_evolution step 121: f(x)= 19202.293865091262
# differential_evolution step 122: f(x)= 19202.293865091262
# differential_evolution step 123: f(x)= 19202.293865091262
# differential_evolution step 124: f(x)= 19202.293865091262
# differential_evolution step 125: f(x)= 19202.293865091262
# differential_evolution step 126: f(x)= 19202.293865091262
# differential_evolution step 127: f(x)= 19202.293865091262
# differential_evolution step 128: f(x)= 19161.418517313057
# differential_evolution step 129: f(x)= 19161.418517313057
# differential_evolution step 130: f(x)= 19161.418517313057
# differential_evolution step 131: f(x)= 19161.418517313057
# differential_evolution step 132: f(x)= 19161.418517313057
# differential_evolution step 133: f(x)= 19152.124888191058
# differential_evolution step 134: f(x)= 19152.124888191058
# differential_evolution step 135: f(x)= 19152.124888191058
# differential_evolution step 136: f(x)= 19152.124888191058
# differential_evolution step 137: f(x)= 19144.21597287248
# differential_evolution step 138: f(x)= 19144.21597287248
# differential_evolution step 139: f(x)= 19141.251818255838
# differential_evolution step 140: f(x)= 19141.251818255838
# differential_evolution step 141: f(x)= 19141.251818255838
# differential_evolution step 142: f(x)= 19141.251818255838
# differential_evolution step 143: f(x)= 19140.919622496313
# differential_evolution step 144: f(x)= 19129.467266978423
# differential_evolution step 145: f(x)= 19129.467266978423
# differential_evolution step 146: f(x)= 19129.467266978423
# differential_evolution step 147: f(x)= 19129.467266978423
# differential_evolution step 148: f(x)= 19129.467266978423
# differential_evolution step 149: f(x)= 19129.467266978423
# differential_evolution step 150: f(x)= 19126.506405920773
# differential_evolution step 151: f(x)= 19126.506405920773
# differential_evolution step 152: f(x)= 19126.506405920773
# differential_evolution step 153: f(x)= 19110.780177181943
# differential_evolution step 154: f(x)= 19110.780177181943
# differential_evolution step 155: f(x)= 19110.780177181943
# differential_evolution step 156: f(x)= 19110.780177181943
# differential_evolution step 157: f(x)= 19110.780177181943
# differential_evolution step 158: f(x)= 19110.780177181943
# differential_evolution step 159: f(x)= 19110.780177181943
# differential_evolution step 160: f(x)= 19110.780177181943
# differential_evolution step 161: f(x)= 19110.780177181943
# differential_evolution step 162: f(x)= 19107.43724695833
# differential_evolution step 163: f(x)= 19107.43724695833
# differential_evolution step 164: f(x)= 19107.43724695833
# differential_evolution step 165: f(x)= 19107.43724695833
# differential_evolution step 166: f(x)= 19107.43724695833
# differential_evolution step 167: f(x)= 19106.284695320657
# differential_evolution step 168: f(x)= 19106.284695320657
# differential_evolution step 169: f(x)= 19106.284695320657
# differential_evolution step 170: f(x)= 19106.284695320657
# differential_evolution step 171: f(x)= 19102.835029833663
# differential_evolution step 172: f(x)= 19102.835029833663
# differential_evolution step 173: f(x)= 19102.835029833663
# differential_evolution step 174: f(x)= 19102.835029833663
# differential_evolution step 175: f(x)= 19102.835029833663
# differential_evolution step 176: f(x)= 19102.835029833663
# differential_evolution step 177: f(x)= 19102.835029833663
# differential_evolution step 178: f(x)= 19102.835029833663
# differential_evolution step 179: f(x)= 19102.835029833663
# differential_evolution step 180: f(x)= 19102.835029833663
# differential_evolution step 181: f(x)= 19100.722067782393
# differential_evolution step 182: f(x)= 19100.722067782393
# differential_evolution step 183: f(x)= 19097.79616702048
# differential_evolution step 184: f(x)= 19097.79616702048
# differential_evolution step 185: f(x)= 19097.79616702048
# differential_evolution step 186: f(x)= 19097.79616702048
# differential_evolution step 187: f(x)= 19097.79616702048
# differential_evolution step 188: f(x)= 19097.79616702048
# differential_evolution step 189: f(x)= 19097.79616702048
# differential_evolution step 190: f(x)= 19097.79616702048
# differential_evolution step 191: f(x)= 19097.79616702048
# differential_evolution step 192: f(x)= 19097.79616702048
# differential_evolution step 193: f(x)= 19097.79616702048
# differential_evolution step 194: f(x)= 19097.79616702048
# differential_evolution step 195: f(x)= 19097.79616702048
# differential_evolution step 196: f(x)= 19097.79616702048
# differential_evolution step 197: f(x)= 19097.79616702048
# differential_evolution step 198: f(x)= 19097.79616702048
# differential_evolution step 199: f(x)= 19097.79616702048
# differential_evolution step 200: f(x)= 19097.79616702048
# differential_evolution step 201: f(x)= 19095.483769285074
# differential_evolution step 202: f(x)= 19095.483769285074
# differential_evolution step 203: f(x)= 19095.483769285074
# differential_evolution step 204: f(x)= 19095.483769285074
# differential_evolution step 205: f(x)= 19095.483769285074
# differential_evolution step 206: f(x)= 19095.483769285074
# differential_evolution step 207: f(x)= 19093.935360005507
# differential_evolution step 208: f(x)= 19093.935360005507
# differential_evolution step 209: f(x)= 19093.935360005507
# differential_evolution step 210: f(x)= 19093.935360005507
# differential_evolution step 211: f(x)= 19093.935360005507
# differential_evolution step 212: f(x)= 19093.935360005507
# differential_evolution step 213: f(x)= 19093.935360005507
# differential_evolution step 214: f(x)= 19093.935360005507
# differential_evolution step 215: f(x)= 19093.935360005507
# differential_evolution step 216: f(x)= 19093.935360005507
# differential_evolution step 217: f(x)= 19093.177469530885
# differential_evolution step 218: f(x)= 19093.177469530885
# differential_evolution step 219: f(x)= 19093.177469530885
# differential_evolution step 220: f(x)= 19093.177469530885
# differential_evolution step 221: f(x)= 19093.177469530885
# differential_evolution step 222: f(x)= 19093.177469530885
# differential_evolution step 223: f(x)= 19091.53248143306
# differential_evolution step 224: f(x)= 19091.53248143306
# differential_evolution step 225: f(x)= 19091.53248143306
# differential_evolution step 226: f(x)= 19091.53248143306
# differential_evolution step 227: f(x)= 19091.005809807393
# differential_evolution step 228: f(x)= 19091.005809807393
# differential_evolution step 229: f(x)= 19091.005809807393
# differential_evolution step 230: f(x)= 19091.005809807393
# differential_evolution step 231: f(x)= 19091.005809807393
# differential_evolution step 232: f(x)= 19090.48366418438
# differential_evolution step 233: f(x)= 19090.48366418438
# differential_evolution step 234: f(x)= 19090.48366418438
# differential_evolution step 235: f(x)= 19090.48366418438
# differential_evolution step 236: f(x)= 19089.806189216964
# differential_evolution step 237: f(x)= 19089.629437121836
# differential_evolution step 238: f(x)= 19089.629437121836
# differential_evolution step 239: f(x)= 19089.629437121836
# differential_evolution step 240: f(x)= 19089.629437121836
# differential_evolution step 241: f(x)= 19089.629437121836
# differential_evolution step 242: f(x)= 19089.629437121836
# differential_evolution step 243: f(x)= 19089.629437121836
# differential_evolution step 244: f(x)= 19089.629437121836
# differential_evolution step 245: f(x)= 19089.629437121836
# differential_evolution step 246: f(x)= 19088.58825160733
# differential_evolution step 247: f(x)= 19088.58825160733
# differential_evolution step 248: f(x)= 19088.58825160733
# differential_evolution step 249: f(x)= 19088.58825160733
# differential_evolution step 250: f(x)= 19088.58825160733
# differential_evolution step 251: f(x)= 19088.58825160733
# differential_evolution step 252: f(x)= 19088.240996890618
# differential_evolution step 253: f(x)= 19088.240996890618
# differential_evolution step 254: f(x)= 19087.877324333505
# differential_evolution step 255: f(x)= 19087.681634993336
# differential_evolution step 256: f(x)= 19087.681634993336
# differential_evolution step 257: f(x)= 19087.681634993336
# differential_evolution step 258: f(x)= 19087.681634993336
# differential_evolution step 259: f(x)= 19087.681634993336
# differential_evolution step 260: f(x)= 19087.548034576565
# differential_evolution step 261: f(x)= 19087.548034576565
# differential_evolution step 262: f(x)= 19087.548034576565
# differential_evolution step 263: f(x)= 19087.323606456834
# differential_evolution step 264: f(x)= 19087.323606456834
# differential_evolution step 265: f(x)= 19087.323606456834
# differential_evolution step 266: f(x)= 19087.323606456834
# differential_evolution step 267: f(x)= 19086.89663900691
# differential_evolution step 268: f(x)= 19086.89663900691
# differential_evolution step 269: f(x)= 19086.565838666305
# differential_evolution step 270: f(x)= 19086.565838666305
# differential_evolution step 271: f(x)= 19086.565838666305
# differential_evolution step 272: f(x)= 19086.565838666305
# differential_evolution step 273: f(x)= 19086.565838666305
# differential_evolution step 274: f(x)= 19086.565838666305
# differential_evolution step 275: f(x)= 19086.565838666305
# differential_evolution step 276: f(x)= 19086.565838666305
# differential_evolution step 277: f(x)= 19086.565838666305
# differential_evolution step 278: f(x)= 19086.565838666305
# differential_evolution step 279: f(x)= 19086.565838666305
# differential_evolution step 280: f(x)= 19086.565838666305
# differential_evolution step 281: f(x)= 19086.565838666305
# differential_evolution step 282: f(x)= 19086.565838666305
# differential_evolution step 283: f(x)= 19086.52805020313
# differential_evolution step 284: f(x)= 19086.52805020313
# differential_evolution step 285: f(x)= 19086.52805020313
# differential_evolution step 286: f(x)= 19086.52805020313
# differential_evolution step 287: f(x)= 19086.52805020313
# differential_evolution step 288: f(x)= 19086.52805020313
# differential_evolution step 289: f(x)= 19086.52805020313
# differential_evolution step 290: f(x)= 19086.52805020313
# differential_evolution step 291: f(x)= 19086.497352178565
# differential_evolution step 292: f(x)= 19086.497352178565
# differential_evolution step 293: f(x)= 19086.497352178565
# differential_evolution step 294: f(x)= 19086.497352178565
# differential_evolution step 295: f(x)= 19086.497352178565
# differential_evolution step 296: f(x)= 19086.497352178565
# differential_evolution step 297: f(x)= 19086.497352178565
# differential_evolution step 298: f(x)= 19086.497352178565
# differential_evolution step 299: f(x)= 19086.497352178565
# differential_evolution step 300: f(x)= 19086.495563204044
# differential_evolution step 301: f(x)= 19086.495563204044
# differential_evolution step 302: f(x)= 19086.495563204044
# differential_evolution step 303: f(x)= 19086.399376847356
# differential_evolution step 304: f(x)= 19086.399376847356
# differential_evolution step 305: f(x)= 19086.399376847356
# differential_evolution step 306: f(x)= 19086.399376847356
# differential_evolution step 307: f(x)= 19086.399376847356
# differential_evolution step 308: f(x)= 19086.399376847356
# differential_evolution step 309: f(x)= 19086.399376847356
# differential_evolution step 310: f(x)= 19086.399376847356
# differential_evolution step 311: f(x)= 19086.36052081106
# differential_evolution step 312: f(x)= 19086.293079987674
# differential_evolution step 313: f(x)= 19086.293079987674
# differential_evolution step 314: f(x)= 19086.293079987674
# differential_evolution step 315: f(x)= 19086.293079987674
# differential_evolution step 316: f(x)= 19086.286113777478
# differential_evolution step 317: f(x)= 19086.241524092606
# differential_evolution step 318: f(x)= 19086.241524092606
# differential_evolution step 319: f(x)= 19086.241524092606
# differential_evolution step 320: f(x)= 19086.241524092606
# differential_evolution step 321: f(x)= 19086.241524092606
# differential_evolution step 322: f(x)= 19086.241524092606
# differential_evolution step 323: f(x)= 19086.241524092606
# differential_evolution step 324: f(x)= 19086.241524092606
# differential_evolution step 325: f(x)= 19086.241524092606
# differential_evolution step 326: f(x)= 19086.241524092606
# differential_evolution step 327: f(x)= 19086.241524092606
# differential_evolution step 328: f(x)= 19086.21381385504
# differential_evolution step 329: f(x)= 19086.21381385504
# differential_evolution step 330: f(x)= 19086.21381385504
# differential_evolution step 331: f(x)= 19086.21381385504
# differential_evolution step 332: f(x)= 19086.21381385504
# differential_evolution step 333: f(x)= 19086.21381385504
# differential_evolution step 334: f(x)= 19086.211305342273
# differential_evolution step 335: f(x)= 19086.211305342273
# differential_evolution step 336: f(x)= 19086.211305342273
# differential_evolution step 337: f(x)= 19086.211305342273
# differential_evolution step 338: f(x)= 19086.207891631835
# differential_evolution step 339: f(x)= 19086.207891631835
# differential_evolution step 340: f(x)= 19086.207891631835
# differential_evolution step 341: f(x)= 19086.207891631835
# differential_evolution step 342: f(x)= 19086.207891631835
# differential_evolution step 343: f(x)= 19086.1962061135
# differential_evolution step 344: f(x)= 19086.1962061135
# differential_evolution step 345: f(x)= 19086.1962061135
# differential_evolution step 346: f(x)= 19086.191331678754
# differential_evolution step 347: f(x)= 19086.191331678754
# differential_evolution step 348: f(x)= 19086.191331678754
# differential_evolution step 349: f(x)= 19086.191331678754
# differential_evolution step 350: f(x)= 19086.167006901804
# differential_evolution step 351: f(x)= 19086.157100052224
# differential_evolution step 352: f(x)= 19086.157100052224
# differential_evolution step 353: f(x)= 19086.157100052224
# differential_evolution step 354: f(x)= 19086.14969422298
# differential_evolution step 355: f(x)= 19086.14969422298
# differential_evolution step 356: f(x)= 19086.14969422298
# differential_evolution step 357: f(x)= 19086.14969422298
# differential_evolution step 358: f(x)= 19086.14969422298
# differential_evolution step 359: f(x)= 19086.148238484115
# differential_evolution step 360: f(x)= 19086.148238484115
# differential_evolution step 361: f(x)= 19086.148238484115
# differential_evolution step 362: f(x)= 19086.148238484115
# differential_evolution step 363: f(x)= 19086.148238484115
# differential_evolution step 364: f(x)= 19086.148238484115
# differential_evolution step 365: f(x)= 19086.133497995837
# differential_evolution step 366: f(x)= 19086.133497995837
# differential_evolution step 367: f(x)= 19086.133497995837
# differential_evolution step 368: f(x)= 19086.133497995837
# differential_evolution step 369: f(x)= 19086.133497995837
# differential_evolution step 370: f(x)= 19086.12244696635
# differential_evolution step 371: f(x)= 19086.12244696635
# differential_evolution step 372: f(x)= 19086.12244696635
# differential_evolution step 373: f(x)= 19086.12244696635
# differential_evolution step 374: f(x)= 19086.12244696635
# differential_evolution step 375: f(x)= 19086.12244696635
# differential_evolution step 376: f(x)= 19086.12244696635
# differential_evolution step 377: f(x)= 19086.12244696635
# differential_evolution step 378: f(x)= 19086.121337356166
# differential_evolution step 379: f(x)= 19086.121337356166
# differential_evolution step 380: f(x)= 19086.121337356166
# differential_evolution step 381: f(x)= 19086.120311171955
# differential_evolution step 382: f(x)= 19086.119330236987
# differential_evolution step 383: f(x)= 19086.119330236987
# differential_evolution step 384: f(x)= 19086.11123350153
# differential_evolution step 385: f(x)= 19086.11123350153
# differential_evolution step 386: f(x)= 19086.11123350153
# differential_evolution step 387: f(x)= 19086.11123350153
# differential_evolution step 388: f(x)= 19086.11123350153
# differential_evolution step 389: f(x)= 19086.11123350153
# differential_evolution step 390: f(x)= 19086.11123350153
# differential_evolution step 391: f(x)= 19086.11123350153
# differential_evolution step 392: f(x)= 19086.108593138262
# differential_evolution step 393: f(x)= 19086.108593138262
# differential_evolution step 394: f(x)= 19086.108593138262
# differential_evolution step 395: f(x)= 19086.108593138262
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=21.0149, n=2.2014, x_0=40.7859
# Sérsic 2: I_e=10.0000, r_e=7.8816, n=0.8232, x_0=45.0000
# Sérsic 3: I_e=4.8568, r_e=8.1614, n=2.0407, x_0=58.5885
# Chi quadro minimo: 19086.095303772283
# True

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bounds = [
    (0, 15),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 45),   # x_0: posizione da 0 a 100

    (0, 15),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 7),
    (0, 50),
    (0.1, 10),
    (55, 65)]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[5], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2, radial_profile_error_continuum_2,
                                                                          sigmas[5], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=14.9916, r_e=3.4546, n=1.8715, x_0=38.7797
# Sérsic 2: I_e=14.8619, r_e=12.9303, n=1.8888, x_0=42.0560
# Sérsic 3: I_e=3.7770, r_e=16.2612, n=2.0773, x_0=58.3999
# [2.40331401e+01 3.73176710e+00 1.29444723e+00 1.47394583e-01
#  5.81000246e+00 3.95407768e+00 2.60156346e-01 1.53441204e-01
#  4.63798710e+00 1.44034622e+01 1.14402337e+00 1.98669924e-02]
# 791.0243493145791

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 27275.60413059845
# differential_evolution step 2: f(x)= 27275.60413059845
# differential_evolution step 3: f(x)= 27275.60413059845
# differential_evolution step 4: f(x)= 21921.213242012018
# differential_evolution step 5: f(x)= 17014.236391921902
# differential_evolution step 6: f(x)= 15402.67197112404
# differential_evolution step 7: f(x)= 15402.67197112404
# differential_evolution step 8: f(x)= 12491.928112986941
# differential_evolution step 9: f(x)= 12491.928112986941
# differential_evolution step 10: f(x)= 12491.928112986941
# differential_evolution step 11: f(x)= 12491.928112986941
# differential_evolution step 12: f(x)= 12491.928112986941
# differential_evolution step 13: f(x)= 12491.928112986941
# differential_evolution step 14: f(x)= 12309.007678726186
# differential_evolution step 15: f(x)= 12309.007678726186
# differential_evolution step 16: f(x)= 12309.007678726186
# differential_evolution step 17: f(x)= 9413.527136093036
# differential_evolution step 18: f(x)= 9413.527136093036
# differential_evolution step 19: f(x)= 9413.527136093036
# differential_evolution step 20: f(x)= 9413.527136093036
# differential_evolution step 21: f(x)= 9101.355223493367
# differential_evolution step 22: f(x)= 9101.355223493367
# differential_evolution step 23: f(x)= 9101.355223493367
# differential_evolution step 24: f(x)= 8941.425164372784
# differential_evolution step 25: f(x)= 8941.425164372784
# differential_evolution step 26: f(x)= 8941.425164372784
# differential_evolution step 27: f(x)= 8941.425164372784
# differential_evolution step 28: f(x)= 8941.425164372784
# differential_evolution step 29: f(x)= 8941.425164372784
# differential_evolution step 30: f(x)= 8941.425164372784
# differential_evolution step 31: f(x)= 8941.425164372784
# differential_evolution step 32: f(x)= 8941.425164372784
# differential_evolution step 33: f(x)= 8543.721523677516
# differential_evolution step 34: f(x)= 8543.721523677516
# differential_evolution step 35: f(x)= 8543.721523677516
# differential_evolution step 36: f(x)= 8543.721523677516
# differential_evolution step 37: f(x)= 8543.721523677516
# differential_evolution step 38: f(x)= 8543.721523677516
# differential_evolution step 39: f(x)= 8543.721523677516
# differential_evolution step 40: f(x)= 8543.721523677516
# differential_evolution step 41: f(x)= 7742.935103191077
# differential_evolution step 42: f(x)= 7731.155164368032
# differential_evolution step 43: f(x)= 7731.155164368032
# differential_evolution step 44: f(x)= 7731.155164368032
# differential_evolution step 45: f(x)= 7731.155164368032
# differential_evolution step 46: f(x)= 7577.623898831178
# differential_evolution step 47: f(x)= 7577.623898831178
# differential_evolution step 48: f(x)= 7577.623898831178
# differential_evolution step 49: f(x)= 7155.485925249213
# differential_evolution step 50: f(x)= 7155.485925249213
# differential_evolution step 51: f(x)= 7155.485925249213
# differential_evolution step 52: f(x)= 7155.485925249213
# differential_evolution step 53: f(x)= 7020.143653411213
# differential_evolution step 54: f(x)= 6961.825437878994
# differential_evolution step 55: f(x)= 6961.825437878994
# differential_evolution step 56: f(x)= 6961.825437878994
# differential_evolution step 57: f(x)= 6719.13648657053
# differential_evolution step 58: f(x)= 6719.13648657053
# differential_evolution step 59: f(x)= 6719.13648657053
# differential_evolution step 60: f(x)= 6719.13648657053
# differential_evolution step 61: f(x)= 6347.7970236573165
# differential_evolution step 62: f(x)= 6347.7970236573165
# differential_evolution step 63: f(x)= 5929.1634133275
# differential_evolution step 64: f(x)= 5929.1634133275
# differential_evolution step 65: f(x)= 5929.1634133275
# differential_evolution step 66: f(x)= 5929.1634133275
# differential_evolution step 67: f(x)= 5929.1634133275
# differential_evolution step 68: f(x)= 5929.1634133275
# differential_evolution step 69: f(x)= 5929.1634133275
# differential_evolution step 70: f(x)= 5929.1634133275
# differential_evolution step 71: f(x)= 5929.1634133275
# differential_evolution step 72: f(x)= 5929.1634133275
# differential_evolution step 73: f(x)= 5929.1634133275
# differential_evolution step 74: f(x)= 5929.1634133275
# differential_evolution step 75: f(x)= 5839.556217064696
# differential_evolution step 76: f(x)= 5839.556217064696
# differential_evolution step 77: f(x)= 5689.231522941812
# differential_evolution step 78: f(x)= 5689.231522941812
# differential_evolution step 79: f(x)= 5689.231522941812
# differential_evolution step 80: f(x)= 5689.231522941812
# differential_evolution step 81: f(x)= 5689.231522941812
# differential_evolution step 82: f(x)= 5594.809388853086
# differential_evolution step 83: f(x)= 5594.809388853086
# differential_evolution step 84: f(x)= 5513.020400370816
# differential_evolution step 85: f(x)= 5513.020400370816
# differential_evolution step 86: f(x)= 5513.020400370816
# differential_evolution step 87: f(x)= 5513.020400370816
# differential_evolution step 88: f(x)= 5513.020400370816
# differential_evolution step 89: f(x)= 5513.020400370816
# differential_evolution step 90: f(x)= 5513.020400370816
# differential_evolution step 91: f(x)= 5513.020400370816
# differential_evolution step 92: f(x)= 5310.0207544472405
# differential_evolution step 93: f(x)= 5310.0207544472405
# differential_evolution step 94: f(x)= 5310.0207544472405
# differential_evolution step 95: f(x)= 5310.0207544472405
# differential_evolution step 96: f(x)= 5310.0207544472405
# differential_evolution step 97: f(x)= 5310.0207544472405
# differential_evolution step 98: f(x)= 5310.0207544472405
# differential_evolution step 99: f(x)= 5231.226795054604
# differential_evolution step 100: f(x)= 5231.226795054604
# differential_evolution step 101: f(x)= 5231.226795054604
# differential_evolution step 102: f(x)= 5125.929418836545
# differential_evolution step 103: f(x)= 5125.929418836545
# differential_evolution step 104: f(x)= 5125.929418836545
# differential_evolution step 105: f(x)= 5125.929418836545
# differential_evolution step 106: f(x)= 5125.929418836545
# differential_evolution step 107: f(x)= 5125.929418836545
# differential_evolution step 108: f(x)= 5125.929418836545
# differential_evolution step 109: f(x)= 5125.929418836545
# differential_evolution step 110: f(x)= 5125.929418836545
# differential_evolution step 111: f(x)= 5125.929418836545
# differential_evolution step 112: f(x)= 5125.929418836545
# differential_evolution step 113: f(x)= 5074.72790325034
# differential_evolution step 114: f(x)= 5074.72790325034
# differential_evolution step 115: f(x)= 5074.72790325034
# differential_evolution step 116: f(x)= 5074.72790325034
# differential_evolution step 117: f(x)= 5074.72790325034
# differential_evolution step 118: f(x)= 5074.72790325034
# differential_evolution step 119: f(x)= 5074.72790325034
# differential_evolution step 120: f(x)= 5074.72790325034
# differential_evolution step 121: f(x)= 5074.72790325034
# differential_evolution step 122: f(x)= 5074.72790325034
# differential_evolution step 123: f(x)= 5056.9997356626645
# differential_evolution step 124: f(x)= 5056.9997356626645
# differential_evolution step 125: f(x)= 5056.9997356626645
# differential_evolution step 126: f(x)= 5056.9997356626645
# differential_evolution step 127: f(x)= 5056.9997356626645
# differential_evolution step 128: f(x)= 5028.347026191543
# differential_evolution step 129: f(x)= 5028.347026191543
# differential_evolution step 130: f(x)= 5011.1150034399025
# differential_evolution step 131: f(x)= 5011.1150034399025
# differential_evolution step 132: f(x)= 5011.1150034399025
# differential_evolution step 133: f(x)= 4972.804678732077
# differential_evolution step 134: f(x)= 4972.804678732077
# differential_evolution step 135: f(x)= 4972.804678732077
# differential_evolution step 136: f(x)= 4972.804678732077
# differential_evolution step 137: f(x)= 4972.804678732077
# differential_evolution step 138: f(x)= 4972.804678732077
# differential_evolution step 139: f(x)= 4972.804678732077
# differential_evolution step 140: f(x)= 4972.804678732077
# differential_evolution step 141: f(x)= 4972.804678732077
# differential_evolution step 142: f(x)= 4972.804678732077
# differential_evolution step 143: f(x)= 4972.804678732077
# differential_evolution step 144: f(x)= 4972.804678732077
# differential_evolution step 145: f(x)= 4972.804678732077
# differential_evolution step 146: f(x)= 4972.804678732077
# differential_evolution step 147: f(x)= 4970.873503316488
# differential_evolution step 148: f(x)= 4970.873503316488
# differential_evolution step 149: f(x)= 4970.873503316488
# differential_evolution step 150: f(x)= 4970.873503316488
# differential_evolution step 151: f(x)= 4970.873503316488
# differential_evolution step 152: f(x)= 4970.873503316488
# differential_evolution step 153: f(x)= 4970.873503316488
# differential_evolution step 154: f(x)= 4970.873503316488
# differential_evolution step 155: f(x)= 4970.873503316488
# differential_evolution step 156: f(x)= 4970.873503316488
# differential_evolution step 157: f(x)= 4970.873503316488
# differential_evolution step 158: f(x)= 4961.207886274129
# differential_evolution step 159: f(x)= 4961.207886274129
# differential_evolution step 160: f(x)= 4961.207886274129
# differential_evolution step 161: f(x)= 4961.207886274129
# differential_evolution step 162: f(x)= 4961.207886274129
# differential_evolution step 163: f(x)= 4957.482372176545
# differential_evolution step 164: f(x)= 4957.482372176545
# differential_evolution step 165: f(x)= 4957.482372176545
# differential_evolution step 166: f(x)= 4955.712972905087
# differential_evolution step 167: f(x)= 4954.695040537987
# differential_evolution step 168: f(x)= 4944.883282020719
# differential_evolution step 169: f(x)= 4944.883282020719
# differential_evolution step 170: f(x)= 4944.883282020719
# differential_evolution step 171: f(x)= 4944.883282020719
# differential_evolution step 172: f(x)= 4944.883282020719
# differential_evolution step 173: f(x)= 4944.883282020719
# differential_evolution step 174: f(x)= 4944.883282020719
# differential_evolution step 175: f(x)= 4944.883282020719
# differential_evolution step 176: f(x)= 4941.174628733972
# differential_evolution step 177: f(x)= 4932.66412110001
# differential_evolution step 178: f(x)= 4932.66412110001
# differential_evolution step 179: f(x)= 4932.66412110001
# differential_evolution step 180: f(x)= 4932.66412110001
# differential_evolution step 181: f(x)= 4930.294319751583
# differential_evolution step 182: f(x)= 4930.294319751583
# differential_evolution step 183: f(x)= 4930.294319751583
# differential_evolution step 184: f(x)= 4930.294319751583
# differential_evolution step 185: f(x)= 4930.294319751583
# differential_evolution step 186: f(x)= 4930.294319751583
# differential_evolution step 187: f(x)= 4930.294319751583
# differential_evolution step 188: f(x)= 4921.927183474161
# differential_evolution step 189: f(x)= 4921.927183474161
# differential_evolution step 190: f(x)= 4918.604698992384
# differential_evolution step 191: f(x)= 4918.604698992384
# differential_evolution step 192: f(x)= 4918.604698992384
# differential_evolution step 193: f(x)= 4918.604698992384
# differential_evolution step 194: f(x)= 4918.604698992384
# differential_evolution step 195: f(x)= 4918.604698992384
# differential_evolution step 196: f(x)= 4918.604698992384
# differential_evolution step 197: f(x)= 4906.728683019707
# differential_evolution step 198: f(x)= 4906.728683019707
# differential_evolution step 199: f(x)= 4906.728683019707
# differential_evolution step 200: f(x)= 4906.728683019707
# differential_evolution step 201: f(x)= 4906.728683019707
# differential_evolution step 202: f(x)= 4906.728683019707
# differential_evolution step 203: f(x)= 4906.728683019707
# differential_evolution step 204: f(x)= 4905.768231942747
# differential_evolution step 205: f(x)= 4905.768231942747
# differential_evolution step 206: f(x)= 4905.332734222187
# differential_evolution step 207: f(x)= 4905.332734222187
# differential_evolution step 208: f(x)= 4905.332734222187
# differential_evolution step 209: f(x)= 4904.271872397514
# differential_evolution step 210: f(x)= 4904.271872397514
# differential_evolution step 211: f(x)= 4904.271872397514
# differential_evolution step 212: f(x)= 4904.271872397514
# differential_evolution step 213: f(x)= 4903.52114796517
# differential_evolution step 214: f(x)= 4903.52114796517
# differential_evolution step 215: f(x)= 4903.52114796517
# differential_evolution step 216: f(x)= 4903.52114796517
# differential_evolution step 217: f(x)= 4903.52114796517
# differential_evolution step 218: f(x)= 4903.52114796517
# differential_evolution step 219: f(x)= 4903.52114796517
# differential_evolution step 220: f(x)= 4903.52114796517
# differential_evolution step 221: f(x)= 4903.52114796517
# differential_evolution step 222: f(x)= 4903.52114796517
# differential_evolution step 223: f(x)= 4903.52114796517
# differential_evolution step 224: f(x)= 4903.52114796517
# differential_evolution step 225: f(x)= 4903.52114796517
# differential_evolution step 226: f(x)= 4903.52114796517
# differential_evolution step 227: f(x)= 4903.52114796517
# differential_evolution step 228: f(x)= 4902.721087842025
# differential_evolution step 229: f(x)= 4901.242051888076
# differential_evolution step 230: f(x)= 4899.6150718641775
# differential_evolution step 231: f(x)= 4899.6150718641775
# differential_evolution step 232: f(x)= 4899.6150718641775
# differential_evolution step 233: f(x)= 4899.6150718641775
# differential_evolution step 234: f(x)= 4899.6150718641775
# differential_evolution step 235: f(x)= 4899.6150718641775
# differential_evolution step 236: f(x)= 4899.6150718641775
# differential_evolution step 237: f(x)= 4899.6150718641775
# differential_evolution step 238: f(x)= 4896.246595430384
# differential_evolution step 239: f(x)= 4895.399185395017
# differential_evolution step 240: f(x)= 4895.399185395017
# differential_evolution step 241: f(x)= 4895.399185395017
# differential_evolution step 242: f(x)= 4895.399185395017
# differential_evolution step 243: f(x)= 4892.987110665654
# differential_evolution step 244: f(x)= 4892.987110665654
# differential_evolution step 245: f(x)= 4892.987110665654
# differential_evolution step 246: f(x)= 4892.987110665654
# differential_evolution step 247: f(x)= 4892.727436336691
# differential_evolution step 248: f(x)= 4892.727436336691
# differential_evolution step 249: f(x)= 4892.727436336691
# differential_evolution step 250: f(x)= 4892.095640074318
# differential_evolution step 251: f(x)= 4892.095640074318
# differential_evolution step 252: f(x)= 4892.095640074318
# differential_evolution step 253: f(x)= 4890.950637204082
# differential_evolution step 254: f(x)= 4890.950637204082
# differential_evolution step 255: f(x)= 4890.950637204082
# differential_evolution step 256: f(x)= 4890.950637204082
# differential_evolution step 257: f(x)= 4890.950637204082
# differential_evolution step 258: f(x)= 4890.371344341384
# differential_evolution step 259: f(x)= 4890.371344341384
# differential_evolution step 260: f(x)= 4890.371344341384
# differential_evolution step 261: f(x)= 4890.168078297601
# differential_evolution step 262: f(x)= 4889.504214362458
# differential_evolution step 263: f(x)= 4889.504214362458
# differential_evolution step 264: f(x)= 4889.504214362458
# differential_evolution step 265: f(x)= 4889.504214362458
# differential_evolution step 266: f(x)= 4889.504214362458
# differential_evolution step 267: f(x)= 4889.504214362458
# differential_evolution step 268: f(x)= 4889.364363362002
# differential_evolution step 269: f(x)= 4889.364363362002
# differential_evolution step 270: f(x)= 4889.364363362002
# differential_evolution step 271: f(x)= 4889.364363362002
# differential_evolution step 272: f(x)= 4889.364363362002
# differential_evolution step 273: f(x)= 4889.364363362002
# differential_evolution step 274: f(x)= 4889.364363362002
# differential_evolution step 275: f(x)= 4888.881676641963
# differential_evolution step 276: f(x)= 4888.881676641963
# differential_evolution step 277: f(x)= 4888.881676641963
# differential_evolution step 278: f(x)= 4888.680697555993
# differential_evolution step 279: f(x)= 4888.64849589145
# differential_evolution step 280: f(x)= 4888.5230301472175
# differential_evolution step 281: f(x)= 4888.5230301472175
# differential_evolution step 282: f(x)= 4888.5230301472175
# differential_evolution step 283: f(x)= 4888.5230301472175
# differential_evolution step 284: f(x)= 4888.5230301472175
# differential_evolution step 285: f(x)= 4888.5230301472175
# differential_evolution step 286: f(x)= 4888.323854790693
# differential_evolution step 287: f(x)= 4888.323854790693
# differential_evolution step 288: f(x)= 4888.323854790693
# differential_evolution step 289: f(x)= 4888.22931160884
# differential_evolution step 290: f(x)= 4888.22931160884
# differential_evolution step 291: f(x)= 4888.22931160884
# differential_evolution step 292: f(x)= 4888.22931160884
# differential_evolution step 293: f(x)= 4888.126813306019
# differential_evolution step 294: f(x)= 4888.126813306019
# differential_evolution step 295: f(x)= 4888.126813306019
# differential_evolution step 296: f(x)= 4888.126813306019
# differential_evolution step 297: f(x)= 4888.126813306019
# differential_evolution step 298: f(x)= 4888.126813306019
# differential_evolution step 299: f(x)= 4888.126813306019
# differential_evolution step 300: f(x)= 4888.0398746310375
# differential_evolution step 301: f(x)= 4888.0398746310375
# differential_evolution step 302: f(x)= 4888.0398746310375
# differential_evolution step 303: f(x)= 4888.0398746310375
# differential_evolution step 304: f(x)= 4888.00503160932
# differential_evolution step 305: f(x)= 4888.00503160932
# differential_evolution step 306: f(x)= 4888.00503160932
# differential_evolution step 307: f(x)= 4888.00503160932
# differential_evolution step 308: f(x)= 4888.00503160932
# differential_evolution step 309: f(x)= 4887.991328782015
# differential_evolution step 310: f(x)= 4887.991328782015
# differential_evolution step 311: f(x)= 4887.991328782015
# differential_evolution step 312: f(x)= 4887.991328782015
# differential_evolution step 313: f(x)= 4887.991328782015
# differential_evolution step 314: f(x)= 4887.991328782015
# differential_evolution step 315: f(x)= 4887.955938598691
# differential_evolution step 316: f(x)= 4887.945661409083
# differential_evolution step 317: f(x)= 4887.945661409083
# differential_evolution step 318: f(x)= 4887.945661409083
# differential_evolution step 319: f(x)= 4887.945661409083
# differential_evolution step 320: f(x)= 4887.945661409083
# differential_evolution step 321: f(x)= 4887.945661409083
# differential_evolution step 322: f(x)= 4887.920337425466
# differential_evolution step 323: f(x)= 4887.920337425466
# differential_evolution step 324: f(x)= 4887.920337425466
# differential_evolution step 325: f(x)= 4887.920337425466
# differential_evolution step 326: f(x)= 4887.904388399601
# differential_evolution step 327: f(x)= 4887.904388399601
# differential_evolution step 328: f(x)= 4887.904388399601
# differential_evolution step 329: f(x)= 4887.904388399601
# differential_evolution step 330: f(x)= 4887.904388399601
# differential_evolution step 331: f(x)= 4887.904388399601
# differential_evolution step 332: f(x)= 4887.903384533404
# differential_evolution step 333: f(x)= 4887.898585125748
# differential_evolution step 334: f(x)= 4887.883365909797
# differential_evolution step 335: f(x)= 4887.883365909797
# differential_evolution step 336: f(x)= 4887.883365909797
# differential_evolution step 337: f(x)= 4887.883365909797
# differential_evolution step 338: f(x)= 4887.876430274471
# differential_evolution step 339: f(x)= 4887.853792013778
# differential_evolution step 340: f(x)= 4887.853792013778
# differential_evolution step 341: f(x)= 4887.853792013778
# differential_evolution step 342: f(x)= 4887.853792013778
# differential_evolution step 343: f(x)= 4887.853792013778
# differential_evolution step 344: f(x)= 4887.853792013778
# differential_evolution step 345: f(x)= 4887.853792013778
# differential_evolution step 346: f(x)= 4887.853792013778
# differential_evolution step 347: f(x)= 4887.853792013778
# differential_evolution step 348: f(x)= 4887.853792013778
# differential_evolution step 349: f(x)= 4887.852315881473
# differential_evolution step 350: f(x)= 4887.852315881473
# differential_evolution step 351: f(x)= 4887.852315881473
# differential_evolution step 352: f(x)= 4887.847113831242
# differential_evolution step 353: f(x)= 4887.844641788999
# differential_evolution step 354: f(x)= 4887.844641788999
# differential_evolution step 355: f(x)= 4887.844641788999
# differential_evolution step 356: f(x)= 4887.844641788999
# differential_evolution step 357: f(x)= 4887.844641788999
# differential_evolution step 358: f(x)= 4887.842841277747
# differential_evolution step 359: f(x)= 4887.842841277747
# differential_evolution step 360: f(x)= 4887.842841277747
# differential_evolution step 361: f(x)= 4887.842841277747
# differential_evolution step 362: f(x)= 4887.842841277747
# differential_evolution step 363: f(x)= 4887.842841277747
# differential_evolution step 364: f(x)= 4887.841227066622
# differential_evolution step 365: f(x)= 4887.840502203697
# differential_evolution step 366: f(x)= 4887.837947234924
# differential_evolution step 367: f(x)= 4887.837396104086
# differential_evolution step 368: f(x)= 4887.837396104086
# differential_evolution step 369: f(x)= 4887.834352198928
# differential_evolution step 370: f(x)= 4887.834352198928
# differential_evolution step 371: f(x)= 4887.834352198928
# differential_evolution step 372: f(x)= 4887.834352198928
# differential_evolution step 373: f(x)= 4887.834352198928
# differential_evolution step 374: f(x)= 4887.833242881997
# differential_evolution step 375: f(x)= 4887.833242881997
# differential_evolution step 376: f(x)= 4887.8327676014
# differential_evolution step 377: f(x)= 4887.832085695698
# differential_evolution step 378: f(x)= 4887.832085695698
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=13.8005, n=1.8789, x_0=40.8357
# Sérsic 2: I_e=10.0000, r_e=11.8875, n=0.1000, x_0=49.2405
# Sérsic 3: I_e=10.0000, r_e=1.7346, n=1.1200, x_0=58.0351
# Chi quadro minimo: 4887.825342018624
# True

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          radial_profile_error_continuum_3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2624\1973153750.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2624\1973153750.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2624\1973153750.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=84.2687, r_e=3.0914, n=0.4524, x_0=40.3063
# Sérsic 2: I_e=1.7608, r_e=32.8220, n=1.9532, x_0=48.5636
# Sérsic 3: I_e=9.1374, r_e=3.1237, n=1.1668, x_0=58.0470
# [3.23166206 0.07683673 0.02860575 0.04505684 0.78147003 9.02369061
#  0.29927374 0.18803523 3.72815937 0.91339166 0.30739056 0.08748227]
# 205.25263379037605

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)
