# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32

# %%
image_cut = image[75:175, 0:1890]
image_error_cut = image_error[75:175, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.03144
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
seeing = 1.984
sigma = seeing / 2.35
n_component = 3

# %%
l_HA
# Out:
# 6769.340719999999

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[75:175, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_789/Mrk-789_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     379   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        60   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 24)*(y < 34)
mask_wv = wv > 4451
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) +
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs):
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (35, 45),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (45, 54),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (54, 65)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 7226.664569614486
# differential_evolution step 2: f(x)= 5842.414992112539
# differential_evolution step 3: f(x)= 5681.204309007735
# differential_evolution step 4: f(x)= 5681.204309007735
# differential_evolution step 5: f(x)= 5681.204309007735
# differential_evolution step 6: f(x)= 3509.1888043568406
# differential_evolution step 7: f(x)= 2102.9257223426584
# differential_evolution step 8: f(x)= 2102.9257223426584
# differential_evolution step 9: f(x)= 2102.9257223426584
# differential_evolution step 10: f(x)= 2102.9257223426584
# differential_evolution step 11: f(x)= 2102.9257223426584
# differential_evolution step 12: f(x)= 2102.9257223426584
# differential_evolution step 13: f(x)= 2102.9257223426584
# differential_evolution step 14: f(x)= 2102.9257223426584
# differential_evolution step 15: f(x)= 2030.8621766714568
# differential_evolution step 16: f(x)= 2030.8621766714568
# differential_evolution step 17: f(x)= 1970.9365225611289
# differential_evolution step 18: f(x)= 1970.9365225611289
# differential_evolution step 19: f(x)= 1917.131637239421
# differential_evolution step 20: f(x)= 1917.131637239421
# differential_evolution step 21: f(x)= 1917.131637239421
# differential_evolution step 22: f(x)= 1522.0457140799126
# differential_evolution step 23: f(x)= 1522.0457140799126
# differential_evolution step 24: f(x)= 1522.0457140799126
# differential_evolution step 25: f(x)= 1522.0457140799126
# differential_evolution step 26: f(x)= 1408.214136903637
# differential_evolution step 27: f(x)= 1408.214136903637
# differential_evolution step 28: f(x)= 1408.214136903637
# differential_evolution step 29: f(x)= 1408.214136903637
# differential_evolution step 30: f(x)= 1408.214136903637
# differential_evolution step 31: f(x)= 1408.214136903637
# differential_evolution step 32: f(x)= 1322.0559991598464
# differential_evolution step 33: f(x)= 1322.0559991598464
# differential_evolution step 34: f(x)= 1322.0559991598464
# differential_evolution step 35: f(x)= 1310.224476911229
# differential_evolution step 36: f(x)= 1273.004417094769
# differential_evolution step 37: f(x)= 1273.004417094769
# differential_evolution step 38: f(x)= 1273.004417094769
# differential_evolution step 39: f(x)= 1273.004417094769
# differential_evolution step 40: f(x)= 1273.004417094769
# differential_evolution step 41: f(x)= 1273.004417094769
# differential_evolution step 42: f(x)= 1265.8188663637054
# differential_evolution step 43: f(x)= 1265.8188663637054
# differential_evolution step 44: f(x)= 1265.8188663637054
# differential_evolution step 45: f(x)= 1265.8188663637054
# differential_evolution step 46: f(x)= 1265.8188663637054
# differential_evolution step 47: f(x)= 1265.8188663637054
# differential_evolution step 48: f(x)= 1252.8183544716362
# differential_evolution step 49: f(x)= 1252.8183544716362
# differential_evolution step 50: f(x)= 1252.8183544716362
# differential_evolution step 51: f(x)= 1252.8183544716362
# differential_evolution step 52: f(x)= 1252.8183544716362
# differential_evolution step 53: f(x)= 1249.6964115961741
# differential_evolution step 54: f(x)= 1249.6964115961741
# differential_evolution step 55: f(x)= 1249.6964115961741
# differential_evolution step 56: f(x)= 1249.6964115961741
# differential_evolution step 57: f(x)= 1233.4685441065278
# differential_evolution step 58: f(x)= 1233.4685441065278
# differential_evolution step 59: f(x)= 1233.4685441065278
# differential_evolution step 60: f(x)= 1233.4685441065278
# differential_evolution step 61: f(x)= 1233.4685441065278
# differential_evolution step 62: f(x)= 1233.4685441065278
# differential_evolution step 63: f(x)= 1233.4685441065278
# differential_evolution step 64: f(x)= 1231.8616610560507
# differential_evolution step 65: f(x)= 1231.8616610560507
# differential_evolution step 66: f(x)= 1231.8616610560507
# differential_evolution step 67: f(x)= 1231.8616610560507
# differential_evolution step 68: f(x)= 1231.8616610560507
# differential_evolution step 69: f(x)= 1231.8616610560507
# differential_evolution step 70: f(x)= 1231.8616610560507
# differential_evolution step 71: f(x)= 1231.8616610560507
# differential_evolution step 72: f(x)= 1231.8616610560507
# differential_evolution step 73: f(x)= 1231.8616610560507
# differential_evolution step 74: f(x)= 1228.8380858422383
# differential_evolution step 75: f(x)= 1228.8380858422383
# differential_evolution step 76: f(x)= 1224.9858814452066
# differential_evolution step 77: f(x)= 1224.9858814452066
# differential_evolution step 78: f(x)= 1224.9858814452066
# differential_evolution step 79: f(x)= 1224.9858814452066
# differential_evolution step 80: f(x)= 1224.9858814452066
# differential_evolution step 81: f(x)= 1224.9858814452066
# differential_evolution step 82: f(x)= 1224.726515510282
# differential_evolution step 83: f(x)= 1219.5909294184644
# differential_evolution step 84: f(x)= 1219.5909294184644
# differential_evolution step 85: f(x)= 1216.8903648042844
# differential_evolution step 86: f(x)= 1216.8903648042844
# differential_evolution step 87: f(x)= 1216.8903648042844
# differential_evolution step 88: f(x)= 1216.8903648042844
# differential_evolution step 89: f(x)= 1211.4384178541034
# differential_evolution step 90: f(x)= 1211.4384178541034
# differential_evolution step 91: f(x)= 1211.4384178541034
# differential_evolution step 92: f(x)= 1211.4384178541034
# differential_evolution step 93: f(x)= 1211.4384178541034
# differential_evolution step 94: f(x)= 1211.4297336599059
# differential_evolution step 95: f(x)= 1211.4297336599059
# differential_evolution step 96: f(x)= 1211.4297336599059
# differential_evolution step 97: f(x)= 1209.2205099525327
# differential_evolution step 98: f(x)= 1209.2205099525327
# differential_evolution step 99: f(x)= 1209.2205099525327
# differential_evolution step 100: f(x)= 1208.8756902602051
# differential_evolution step 101: f(x)= 1208.8756902602051
# differential_evolution step 102: f(x)= 1208.8756902602051
# differential_evolution step 103: f(x)= 1208.8756902602051
# differential_evolution step 104: f(x)= 1208.8756902602051
# differential_evolution step 105: f(x)= 1204.290324616016
# differential_evolution step 106: f(x)= 1204.290324616016
# differential_evolution step 107: f(x)= 1204.290324616016
# differential_evolution step 108: f(x)= 1204.290324616016
# differential_evolution step 109: f(x)= 1204.290324616016
# differential_evolution step 110: f(x)= 1204.290324616016
# differential_evolution step 111: f(x)= 1204.290324616016
# differential_evolution step 112: f(x)= 1204.290324616016
# differential_evolution step 113: f(x)= 1202.1271463342955
# differential_evolution step 114: f(x)= 1202.1271463342955
# differential_evolution step 115: f(x)= 1202.1271463342955
# differential_evolution step 116: f(x)= 1202.1271463342955
# differential_evolution step 117: f(x)= 1202.1271463342955
# differential_evolution step 118: f(x)= 1201.719976331151
# differential_evolution step 119: f(x)= 1201.719976331151
# differential_evolution step 120: f(x)= 1201.719976331151
# differential_evolution step 121: f(x)= 1201.719976331151
# differential_evolution step 122: f(x)= 1201.719976331151
# differential_evolution step 123: f(x)= 1201.719976331151
# differential_evolution step 124: f(x)= 1201.719976331151
# differential_evolution step 125: f(x)= 1201.719976331151
# differential_evolution step 126: f(x)= 1201.719976331151
# differential_evolution step 127: f(x)= 1201.719976331151
# differential_evolution step 128: f(x)= 1201.719976331151
# differential_evolution step 129: f(x)= 1201.380939469734
# differential_evolution step 130: f(x)= 1200.1620173929732
# differential_evolution step 131: f(x)= 1200.1620173929732
# differential_evolution step 132: f(x)= 1200.1620173929732
# differential_evolution step 133: f(x)= 1200.1620173929732
# differential_evolution step 134: f(x)= 1200.1620173929732
# differential_evolution step 135: f(x)= 1200.1620173929732
# differential_evolution step 136: f(x)= 1200.1620173929732
# differential_evolution step 137: f(x)= 1200.1620173929732
# differential_evolution step 138: f(x)= 1200.1620173929732
# differential_evolution step 139: f(x)= 1200.1620173929732
# differential_evolution step 140: f(x)= 1200.1620173929732
# differential_evolution step 141: f(x)= 1200.1620173929732
# differential_evolution step 142: f(x)= 1200.1620173929732
# differential_evolution step 143: f(x)= 1200.1620173929732
# differential_evolution step 144: f(x)= 1199.9424634048821
# differential_evolution step 145: f(x)= 1199.9424634048821
# differential_evolution step 146: f(x)= 1199.7149101010637
# differential_evolution step 147: f(x)= 1199.7149101010637
# differential_evolution step 148: f(x)= 1199.1425758347434
# differential_evolution step 149: f(x)= 1199.1425758347434
# differential_evolution step 150: f(x)= 1199.1425758347434
# differential_evolution step 151: f(x)= 1199.1119272417075
# differential_evolution step 152: f(x)= 1199.1119272417075
# differential_evolution step 153: f(x)= 1199.1119272417075
# differential_evolution step 154: f(x)= 1198.6264027236664
# differential_evolution step 155: f(x)= 1198.6264027236664
# differential_evolution step 156: f(x)= 1198.6264027236664
# differential_evolution step 157: f(x)= 1198.6264027236664
# differential_evolution step 158: f(x)= 1198.6264027236664
# differential_evolution step 159: f(x)= 1198.6264027236664
# differential_evolution step 160: f(x)= 1198.5473378951567
# differential_evolution step 161: f(x)= 1198.5473378951567
# differential_evolution step 162: f(x)= 1198.5473378951567
# differential_evolution step 163: f(x)= 1198.521241169293
# differential_evolution step 164: f(x)= 1198.3482829106904
# differential_evolution step 165: f(x)= 1198.3452038758523
# differential_evolution step 166: f(x)= 1198.3452038758523
# differential_evolution step 167: f(x)= 1198.2230157988201
# differential_evolution step 168: f(x)= 1198.1692232680157
# differential_evolution step 169: f(x)= 1198.1488689833996
# differential_evolution step 170: f(x)= 1198.0652429079844
# differential_evolution step 171: f(x)= 1198.0652429079844
# differential_evolution step 172: f(x)= 1198.0652429079844
# differential_evolution step 173: f(x)= 1198.0652429079844
# differential_evolution step 174: f(x)= 1198.0652429079844
# differential_evolution step 175: f(x)= 1198.0652429079844
# differential_evolution step 176: f(x)= 1198.0652429079844
# differential_evolution step 177: f(x)= 1198.0652429079844
# differential_evolution step 178: f(x)= 1198.0652429079844
# differential_evolution step 179: f(x)= 1198.0652429079844
# differential_evolution step 180: f(x)= 1198.0075563839864
# differential_evolution step 181: f(x)= 1198.0075563839864
# differential_evolution step 182: f(x)= 1198.0075563839864
# differential_evolution step 183: f(x)= 1198.0075563839864
# differential_evolution step 184: f(x)= 1198.0075563839864
# differential_evolution step 185: f(x)= 1198.0075563839864
# differential_evolution step 186: f(x)= 1198.0075563839864
# differential_evolution step 187: f(x)= 1198.0075563839864
# differential_evolution step 188: f(x)= 1198.0075563839864
# differential_evolution step 189: f(x)= 1197.9923889332847
# differential_evolution step 190: f(x)= 1197.9923889332847
# differential_evolution step 191: f(x)= 1197.97874763374
# differential_evolution step 192: f(x)= 1197.9617097758971
# differential_evolution step 193: f(x)= 1197.9617097758971
# differential_evolution step 194: f(x)= 1197.9507211408618
# differential_evolution step 195: f(x)= 1197.9507211408618
# differential_evolution step 196: f(x)= 1197.9507211408618
# differential_evolution step 197: f(x)= 1197.9507211408618
# differential_evolution step 198: f(x)= 1197.9507211408618
# differential_evolution step 199: f(x)= 1197.9507211408618
# differential_evolution step 200: f(x)= 1197.9507211408618
# differential_evolution step 201: f(x)= 1197.9129042689874
# differential_evolution step 202: f(x)= 1197.9129042689874
# differential_evolution step 203: f(x)= 1197.9129042689874
# differential_evolution step 204: f(x)= 1197.9129042689874
# differential_evolution step 205: f(x)= 1197.9129042689874
# differential_evolution step 206: f(x)= 1197.9129042689874
# differential_evolution step 207: f(x)= 1197.9129042689874
# differential_evolution step 208: f(x)= 1197.9129042689874
# differential_evolution step 209: f(x)= 1197.9129042689874
# differential_evolution step 210: f(x)= 1197.9129042689874
# differential_evolution step 211: f(x)= 1197.9129042689874
# differential_evolution step 212: f(x)= 1197.9101358155963
# differential_evolution step 213: f(x)= 1197.9101358155963
# differential_evolution step 214: f(x)= 1197.9052839572523
# differential_evolution step 215: f(x)= 1197.9052839572523
# differential_evolution step 216: f(x)= 1197.9052839572523
# differential_evolution step 217: f(x)= 1197.9052839572523
# differential_evolution step 218: f(x)= 1197.9012248523636
# differential_evolution step 219: f(x)= 1197.8946807023676
# differential_evolution step 220: f(x)= 1197.8946807023676
# differential_evolution step 221: f(x)= 1197.8946807023676
# differential_evolution step 222: f(x)= 1197.8946807023676
# differential_evolution step 223: f(x)= 1197.8946807023676
# differential_evolution step 224: f(x)= 1197.8946807023676
# differential_evolution step 225: f(x)= 1197.8946807023676
# differential_evolution step 226: f(x)= 1197.8946807023676
# differential_evolution step 227: f(x)= 1197.8946807023676
# differential_evolution step 228: f(x)= 1197.8946807023676
# differential_evolution step 229: f(x)= 1197.8946807023676
# differential_evolution step 230: f(x)= 1197.8946807023676
# differential_evolution step 231: f(x)= 1197.8928250065987
# differential_evolution step 232: f(x)= 1197.8928250065987
# differential_evolution step 233: f(x)= 1197.8898945867422
# differential_evolution step 234: f(x)= 1197.8898945867422
# differential_evolution step 235: f(x)= 1197.8898945867422
# differential_evolution step 236: f(x)= 1197.8898945867422
# differential_evolution step 237: f(x)= 1197.8898945867422
# differential_evolution step 238: f(x)= 1197.8875141749504
# differential_evolution step 239: f(x)= 1197.8875141749504
# differential_evolution step 240: f(x)= 1197.8875141749504
# differential_evolution step 241: f(x)= 1197.8858899186569
# differential_evolution step 242: f(x)= 1197.8848297005513
# differential_evolution step 243: f(x)= 1197.8844616747313
# differential_evolution step 244: f(x)= 1197.8844616747313
# differential_evolution step 245: f(x)= 1197.8844616747313
# differential_evolution step 246: f(x)= 1197.8844616747313
# differential_evolution step 247: f(x)= 1197.8844616747313
# differential_evolution step 248: f(x)= 1197.8842480922349
# differential_evolution step 249: f(x)= 1197.8837202158884
# differential_evolution step 250: f(x)= 1197.8829590114383
# differential_evolution step 251: f(x)= 1197.8816057407773
# differential_evolution step 252: f(x)= 1197.8816057407773
# differential_evolution step 253: f(x)= 1197.8816057407773
# differential_evolution step 254: f(x)= 1197.8816057407773
# differential_evolution step 255: f(x)= 1197.8816057407773
# differential_evolution step 256: f(x)= 1197.8816057407773
# differential_evolution step 257: f(x)= 1197.8816057407773
# differential_evolution step 258: f(x)= 1197.8816057407773
# differential_evolution step 259: f(x)= 1197.8815876723775
# differential_evolution step 260: f(x)= 1197.8815876723775
# differential_evolution step 261: f(x)= 1197.8815876723775
# differential_evolution step 262: f(x)= 1197.880812240626
# differential_evolution step 263: f(x)= 1197.880812240626
# differential_evolution step 264: f(x)= 1197.8804559052091
# differential_evolution step 265: f(x)= 1197.8800985407318
# differential_evolution step 266: f(x)= 1197.8800897881017
# differential_evolution step 267: f(x)= 1197.8798849193183
# differential_evolution step 268: f(x)= 1197.8798849193183
# differential_evolution step 269: f(x)= 1197.8798849193183
# differential_evolution step 270: f(x)= 1197.8798849193183
# differential_evolution step 271: f(x)= 1197.8798849193183
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=34.7695, n=3.3523, x_0=39.4243
# Sérsic 2: I_e=1.0000, r_e=12.2741, n=1.8403, x_0=48.9677
# Sérsic 3: I_e=1.0000, r_e=7.1364, n=2.1414, x_0=57.1228
# Chi quadro minimo: 1197.8798849193183
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HA, r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_HA, covariance_HA = curve_fit(model_convolved, x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, radial_profile_error_HA,
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=13.7486, r_e=4.2058, n=1.3625, x_0=39.3217
# Sérsic 2: I_e=12.5531, r_e=6.7350, n=0.1060, x_0=44.6136
# Sérsic 3: I_e=3.5016, r_e=5.9281, n=1.2371, x_0=56.9392
# [1.8554462  0.26711049 0.11077717 0.06618654 1.5433129  1.10031342
#  0.0449558  0.33414364 0.68900671 0.67744074 0.15123885 0.12743521]
# 224.0262131852306

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-(seeing/2), x_0_HA[0]+(seeing/2)),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-(seeing/2), x_0_HA[1]+(seeing/2)),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-(seeing/2), x_0_HA[2]+(seeing/2)),

]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 227.4627482632953
# differential_evolution step 2: f(x)= 227.4627482632953
# differential_evolution step 3: f(x)= 227.4627482632953
# differential_evolution step 4: f(x)= 227.4627482632953
# differential_evolution step 5: f(x)= 152.42245887312777
# differential_evolution step 6: f(x)= 152.42245887312777
# differential_evolution step 7: f(x)= 152.42245887312777
# differential_evolution step 8: f(x)= 152.42245887312777
# differential_evolution step 9: f(x)= 152.42245887312777
# differential_evolution step 10: f(x)= 141.49338899326148
# differential_evolution step 11: f(x)= 141.49338899326148
# differential_evolution step 12: f(x)= 141.49338899326148
# differential_evolution step 13: f(x)= 141.49338899326148
# differential_evolution step 14: f(x)= 141.49338899326148
# differential_evolution step 15: f(x)= 141.49338899326148
# differential_evolution step 16: f(x)= 114.34564030115266
# differential_evolution step 17: f(x)= 114.34564030115266
# differential_evolution step 18: f(x)= 114.34564030115266
# differential_evolution step 19: f(x)= 114.34564030115266
# differential_evolution step 20: f(x)= 114.34564030115266
# differential_evolution step 21: f(x)= 114.34564030115266
# differential_evolution step 22: f(x)= 114.34564030115266
# differential_evolution step 23: f(x)= 114.34564030115266
# differential_evolution step 24: f(x)= 109.52037389789665
# differential_evolution step 25: f(x)= 109.52037389789665
# differential_evolution step 26: f(x)= 109.52037389789665
# differential_evolution step 27: f(x)= 109.52037389789665
# differential_evolution step 28: f(x)= 105.86021778218652
# differential_evolution step 29: f(x)= 102.76979654797215
# differential_evolution step 30: f(x)= 102.76979654797215
# differential_evolution step 31: f(x)= 102.76979654797215
# differential_evolution step 32: f(x)= 102.76979654797215
# differential_evolution step 33: f(x)= 102.76979654797215
# differential_evolution step 34: f(x)= 102.76979654797215
# differential_evolution step 35: f(x)= 102.76979654797215
# differential_evolution step 36: f(x)= 99.17859631718336
# differential_evolution step 37: f(x)= 99.17859631718336
# differential_evolution step 38: f(x)= 95.37293858934211
# differential_evolution step 39: f(x)= 95.37293858934211
# differential_evolution step 40: f(x)= 95.37293858934211
# differential_evolution step 41: f(x)= 95.37293858934211
# differential_evolution step 42: f(x)= 95.3555250248492
# differential_evolution step 43: f(x)= 95.3555250248492
# differential_evolution step 44: f(x)= 95.3555250248492
# differential_evolution step 45: f(x)= 95.3555250248492
# differential_evolution step 46: f(x)= 95.3555250248492
# differential_evolution step 47: f(x)= 91.58664056919146
# differential_evolution step 48: f(x)= 91.58664056919146
# differential_evolution step 49: f(x)= 89.51181390411416
# differential_evolution step 50: f(x)= 89.51181390411416
# differential_evolution step 51: f(x)= 88.95842796680671
# differential_evolution step 52: f(x)= 88.95842796680671
# differential_evolution step 53: f(x)= 88.32364501747689
# differential_evolution step 54: f(x)= 87.69386083582148
# differential_evolution step 55: f(x)= 87.33582558767746
# differential_evolution step 56: f(x)= 84.05469434897302
# differential_evolution step 57: f(x)= 84.05469434897302
# differential_evolution step 58: f(x)= 84.05469434897302
# differential_evolution step 59: f(x)= 84.05469434897302
# differential_evolution step 60: f(x)= 84.05469434897302
# differential_evolution step 61: f(x)= 84.05469434897302
# differential_evolution step 62: f(x)= 84.05469434897302
# differential_evolution step 63: f(x)= 84.05469434897302
# differential_evolution step 64: f(x)= 84.05469434897302
# differential_evolution step 65: f(x)= 84.05469434897302
# differential_evolution step 66: f(x)= 84.05469434897302
# differential_evolution step 67: f(x)= 83.81016673565834
# differential_evolution step 68: f(x)= 83.81016673565834
# differential_evolution step 69: f(x)= 83.47693378304177
# differential_evolution step 70: f(x)= 80.78109944841924
# differential_evolution step 71: f(x)= 80.65918557597624
# differential_evolution step 72: f(x)= 80.65918557597624
# differential_evolution step 73: f(x)= 80.65918557597624
# differential_evolution step 74: f(x)= 78.66093331664398
# differential_evolution step 75: f(x)= 77.94151494065548
# differential_evolution step 76: f(x)= 77.94151494065548
# differential_evolution step 77: f(x)= 77.94151494065548
# differential_evolution step 78: f(x)= 74.68893360913059
# differential_evolution step 79: f(x)= 74.68893360913059
# differential_evolution step 80: f(x)= 74.68893360913059
# differential_evolution step 81: f(x)= 74.68893360913059
# differential_evolution step 82: f(x)= 74.68893360913059
# differential_evolution step 83: f(x)= 74.68893360913059
# differential_evolution step 84: f(x)= 74.68893360913059
# differential_evolution step 85: f(x)= 73.25042745027487
# differential_evolution step 86: f(x)= 72.10789436729317
# differential_evolution step 87: f(x)= 72.006486109898
# differential_evolution step 88: f(x)= 72.006486109898
# differential_evolution step 89: f(x)= 71.63941577460301
# differential_evolution step 90: f(x)= 65.85427246715349
# differential_evolution step 91: f(x)= 65.85427246715349
# differential_evolution step 92: f(x)= 65.85427246715349
# differential_evolution step 93: f(x)= 65.85427246715349
# differential_evolution step 94: f(x)= 65.6972129320814
# differential_evolution step 95: f(x)= 65.6972129320814
# differential_evolution step 96: f(x)= 65.6972129320814
# differential_evolution step 97: f(x)= 65.6972129320814
# differential_evolution step 98: f(x)= 65.34819670137912
# differential_evolution step 99: f(x)= 65.34819670137912
# differential_evolution step 100: f(x)= 65.34819670137912
# differential_evolution step 101: f(x)= 65.34819670137912
# differential_evolution step 102: f(x)= 65.34819670137912
# differential_evolution step 103: f(x)= 65.09448054823702
# differential_evolution step 104: f(x)= 65.09448054823702
# differential_evolution step 105: f(x)= 65.09448054823702
# differential_evolution step 106: f(x)= 65.09448054823702
# differential_evolution step 107: f(x)= 65.09448054823702
# differential_evolution step 108: f(x)= 65.09448054823702
# differential_evolution step 109: f(x)= 65.09448054823702
# differential_evolution step 110: f(x)= 65.09448054823702
# differential_evolution step 111: f(x)= 65.09448054823702
# differential_evolution step 112: f(x)= 65.09448054823702
# differential_evolution step 113: f(x)= 63.70979628195107
# differential_evolution step 114: f(x)= 63.37501975851132
# differential_evolution step 115: f(x)= 63.37501975851132
# differential_evolution step 116: f(x)= 63.37501975851132
# differential_evolution step 117: f(x)= 63.37501975851132
# differential_evolution step 118: f(x)= 63.37501975851132
# differential_evolution step 119: f(x)= 63.37501975851132
# differential_evolution step 120: f(x)= 62.42902335004145
# differential_evolution step 121: f(x)= 62.187903860004965
# differential_evolution step 122: f(x)= 62.187903860004965
# differential_evolution step 123: f(x)= 60.74791006906771
# differential_evolution step 124: f(x)= 60.74791006906771
# differential_evolution step 125: f(x)= 60.74791006906771
# differential_evolution step 126: f(x)= 60.393082317504984
# differential_evolution step 127: f(x)= 60.393082317504984
# differential_evolution step 128: f(x)= 60.393082317504984
# differential_evolution step 129: f(x)= 60.393082317504984
# differential_evolution step 130: f(x)= 60.393082317504984
# differential_evolution step 131: f(x)= 60.393082317504984
# differential_evolution step 132: f(x)= 60.393082317504984
# differential_evolution step 133: f(x)= 60.393082317504984
# differential_evolution step 134: f(x)= 60.393082317504984
# differential_evolution step 135: f(x)= 60.393082317504984
# differential_evolution step 136: f(x)= 60.393082317504984
# differential_evolution step 137: f(x)= 60.393082317504984
# differential_evolution step 138: f(x)= 59.55057528766925
# differential_evolution step 139: f(x)= 58.26146370309963
# differential_evolution step 140: f(x)= 57.58476019551468
# differential_evolution step 141: f(x)= 56.67079205386741
# differential_evolution step 142: f(x)= 56.67079205386741
# differential_evolution step 143: f(x)= 56.35219466122335
# differential_evolution step 144: f(x)= 56.027821568549136
# differential_evolution step 145: f(x)= 56.027821568549136
# differential_evolution step 146: f(x)= 56.027821568549136
# differential_evolution step 147: f(x)= 56.027821568549136
# differential_evolution step 148: f(x)= 56.027821568549136
# differential_evolution step 149: f(x)= 54.79465122810271
# differential_evolution step 150: f(x)= 54.79465122810271
# differential_evolution step 151: f(x)= 54.06001244667574
# differential_evolution step 152: f(x)= 53.952099500090185
# differential_evolution step 153: f(x)= 53.952099500090185
# differential_evolution step 154: f(x)= 53.952099500090185
# differential_evolution step 155: f(x)= 53.952099500090185
# differential_evolution step 156: f(x)= 53.952099500090185
# differential_evolution step 157: f(x)= 53.952099500090185
# differential_evolution step 158: f(x)= 52.98948717114854
# differential_evolution step 159: f(x)= 52.98948717114854
# differential_evolution step 160: f(x)= 52.98948717114854
# differential_evolution step 161: f(x)= 52.32555747690352
# differential_evolution step 162: f(x)= 52.32555747690352
# differential_evolution step 163: f(x)= 52.32555747690352
# differential_evolution step 164: f(x)= 52.32555747690352
# differential_evolution step 165: f(x)= 52.32555747690352
# differential_evolution step 166: f(x)= 52.32555747690352
# differential_evolution step 167: f(x)= 52.32555747690352
# differential_evolution step 168: f(x)= 52.32555747690352
# differential_evolution step 169: f(x)= 52.32555747690352
# differential_evolution step 170: f(x)= 52.32555747690352
# differential_evolution step 171: f(x)= 52.32555747690352
# differential_evolution step 172: f(x)= 51.87150177752868
# differential_evolution step 173: f(x)= 51.87150177752868
# differential_evolution step 174: f(x)= 50.81135826162335
# differential_evolution step 175: f(x)= 50.81135826162335
# differential_evolution step 176: f(x)= 50.81135826162335
# differential_evolution step 177: f(x)= 50.81135826162335
# differential_evolution step 178: f(x)= 50.81135826162335
# differential_evolution step 179: f(x)= 50.81135826162335
# differential_evolution step 180: f(x)= 50.81135826162335
# differential_evolution step 181: f(x)= 50.81135826162335
# differential_evolution step 182: f(x)= 50.81135826162335
# differential_evolution step 183: f(x)= 50.81135826162335
# differential_evolution step 184: f(x)= 50.81135826162335
# differential_evolution step 185: f(x)= 50.81135826162335
# differential_evolution step 186: f(x)= 50.81135826162335
# differential_evolution step 187: f(x)= 50.81135826162335
# differential_evolution step 188: f(x)= 50.81135826162335
# differential_evolution step 189: f(x)= 50.81135826162335
# differential_evolution step 190: f(x)= 50.48844633416028
# differential_evolution step 191: f(x)= 50.48844633416028
# differential_evolution step 192: f(x)= 50.48844633416028
# differential_evolution step 193: f(x)= 50.48844633416028
# differential_evolution step 194: f(x)= 50.48844633416028
# differential_evolution step 195: f(x)= 50.48844633416028
# differential_evolution step 196: f(x)= 50.48844633416028
# differential_evolution step 197: f(x)= 50.48844633416028
# differential_evolution step 198: f(x)= 50.48844633416028
# differential_evolution step 199: f(x)= 50.48844633416028
# differential_evolution step 200: f(x)= 50.48844633416028
# differential_evolution step 201: f(x)= 50.48844633416028
# differential_evolution step 202: f(x)= 50.48844633416028
# differential_evolution step 203: f(x)= 50.48844633416028
# differential_evolution step 204: f(x)= 50.48844633416028
# differential_evolution step 205: f(x)= 50.48844633416028
# differential_evolution step 206: f(x)= 50.48844633416028
# differential_evolution step 207: f(x)= 50.48844633416028
# differential_evolution step 208: f(x)= 50.48844633416028
# differential_evolution step 209: f(x)= 50.48844633416028
# differential_evolution step 210: f(x)= 50.48844633416028
# differential_evolution step 211: f(x)= 50.48844633416028
# differential_evolution step 212: f(x)= 50.48844633416028
# differential_evolution step 213: f(x)= 50.48844633416028
# differential_evolution step 214: f(x)= 50.48844633416028
# differential_evolution step 215: f(x)= 50.48844633416028
# differential_evolution step 216: f(x)= 50.48844633416028
# differential_evolution step 217: f(x)= 50.38969395072428
# differential_evolution step 218: f(x)= 50.230376122680056
# differential_evolution step 219: f(x)= 50.230376122680056
# differential_evolution step 220: f(x)= 50.230376122680056
# differential_evolution step 221: f(x)= 50.151606236258566
# differential_evolution step 222: f(x)= 50.151606236258566
# differential_evolution step 223: f(x)= 50.151606236258566
# differential_evolution step 224: f(x)= 50.151606236258566
# differential_evolution step 225: f(x)= 50.151606236258566
# differential_evolution step 226: f(x)= 50.151606236258566
# differential_evolution step 227: f(x)= 50.151606236258566
# differential_evolution step 228: f(x)= 50.0935796672287
# differential_evolution step 229: f(x)= 50.0935796672287
# differential_evolution step 230: f(x)= 50.0935796672287
# differential_evolution step 231: f(x)= 50.0935796672287
# differential_evolution step 232: f(x)= 50.0935796672287
# differential_evolution step 233: f(x)= 50.0935796672287
# differential_evolution step 234: f(x)= 50.0935796672287
# differential_evolution step 235: f(x)= 50.0935796672287
# differential_evolution step 236: f(x)= 50.0935796672287
# differential_evolution step 237: f(x)= 50.0935796672287
# differential_evolution step 238: f(x)= 50.0935796672287
# differential_evolution step 239: f(x)= 50.0935796672287
# differential_evolution step 240: f(x)= 49.81087907405847
# differential_evolution step 241: f(x)= 49.81087907405847
# differential_evolution step 242: f(x)= 49.81087907405847
# differential_evolution step 243: f(x)= 49.81087907405847
# differential_evolution step 244: f(x)= 49.81087907405847
# differential_evolution step 245: f(x)= 49.81087907405847
# differential_evolution step 246: f(x)= 49.800746325955224
# differential_evolution step 247: f(x)= 49.800746325955224
# differential_evolution step 248: f(x)= 49.75369393652731
# differential_evolution step 249: f(x)= 49.75369393652731
# differential_evolution step 250: f(x)= 49.75369393652731
# differential_evolution step 251: f(x)= 49.75369393652731
# differential_evolution step 252: f(x)= 49.75369393652731
# differential_evolution step 253: f(x)= 49.75369393652731
# differential_evolution step 254: f(x)= 49.75369393652731
# differential_evolution step 255: f(x)= 49.75369393652731
# differential_evolution step 256: f(x)= 49.721225309897946
# differential_evolution step 257: f(x)= 49.721225309897946
# differential_evolution step 258: f(x)= 49.721225309897946
# differential_evolution step 259: f(x)= 49.721225309897946
# differential_evolution step 260: f(x)= 49.721225309897946
# differential_evolution step 261: f(x)= 49.721225309897946
# differential_evolution step 262: f(x)= 49.721225309897946
# differential_evolution step 263: f(x)= 49.721225309897946
# differential_evolution step 264: f(x)= 49.67814138723265
# differential_evolution step 265: f(x)= 49.67814138723265
# differential_evolution step 266: f(x)= 49.65305200293147
# differential_evolution step 267: f(x)= 49.65305200293147
# differential_evolution step 268: f(x)= 49.65305200293147
# differential_evolution step 269: f(x)= 49.65305200293147
# differential_evolution step 270: f(x)= 49.65305200293147
# differential_evolution step 271: f(x)= 49.65305200293147
# differential_evolution step 272: f(x)= 49.637218931245265
# differential_evolution step 273: f(x)= 49.637218931245265
# differential_evolution step 274: f(x)= 49.60570104455939
# differential_evolution step 275: f(x)= 49.60570104455939
# differential_evolution step 276: f(x)= 49.60570104455939
# differential_evolution step 277: f(x)= 49.60570104455939
# differential_evolution step 278: f(x)= 49.60570104455939
# differential_evolution step 279: f(x)= 49.60570104455939
# differential_evolution step 280: f(x)= 49.60570104455939
# differential_evolution step 281: f(x)= 49.58448286833124
# differential_evolution step 282: f(x)= 49.58448286833124
# differential_evolution step 283: f(x)= 49.58448286833124
# differential_evolution step 284: f(x)= 49.58448286833124
# differential_evolution step 285: f(x)= 49.579853679608576
# differential_evolution step 286: f(x)= 49.55527237814268
# differential_evolution step 287: f(x)= 49.55527237814268
# differential_evolution step 288: f(x)= 49.53875067786073
# differential_evolution step 289: f(x)= 49.53875067786073
# differential_evolution step 290: f(x)= 49.53875067786073
# differential_evolution step 291: f(x)= 49.53875067786073
# differential_evolution step 292: f(x)= 49.53875067786073
# differential_evolution step 293: f(x)= 49.53875067786073
# differential_evolution step 294: f(x)= 49.53875067786073
# differential_evolution step 295: f(x)= 49.53875067786073
# differential_evolution step 296: f(x)= 49.5373645460111
# differential_evolution step 297: f(x)= 49.5373645460111
# differential_evolution step 298: f(x)= 49.5373645460111
# differential_evolution step 299: f(x)= 49.5373645460111
# differential_evolution step 300: f(x)= 49.5373645460111
# differential_evolution step 301: f(x)= 49.5373645460111
# differential_evolution step 302: f(x)= 49.5373645460111
# differential_evolution step 303: f(x)= 49.53673253149368
# differential_evolution step 304: f(x)= 49.53550210531652
# differential_evolution step 305: f(x)= 49.5350304996616
# differential_evolution step 306: f(x)= 49.5350304996616
# differential_evolution step 307: f(x)= 49.5350304996616
# differential_evolution step 308: f(x)= 49.5350304996616
# differential_evolution step 309: f(x)= 49.52924851657593
# differential_evolution step 310: f(x)= 49.51872629167495
# differential_evolution step 311: f(x)= 49.51872629167495
# differential_evolution step 312: f(x)= 49.51872629167495
# differential_evolution step 313: f(x)= 49.51872629167495
# differential_evolution step 314: f(x)= 49.51872629167495
# differential_evolution step 315: f(x)= 49.501857484738075
# differential_evolution step 316: f(x)= 49.501857484738075
# differential_evolution step 317: f(x)= 49.501857484738075
# differential_evolution step 318: f(x)= 49.501857484738075
# differential_evolution step 319: f(x)= 49.501857484738075
# differential_evolution step 320: f(x)= 49.501857484738075
# differential_evolution step 321: f(x)= 49.501857484738075
# differential_evolution step 322: f(x)= 49.501857484738075
# differential_evolution step 323: f(x)= 49.501857484738075
# differential_evolution step 324: f(x)= 49.501857484738075
# differential_evolution step 325: f(x)= 49.501857484738075
# differential_evolution step 326: f(x)= 49.50083256178246
# differential_evolution step 327: f(x)= 49.49751066218015
# differential_evolution step 328: f(x)= 49.49751066218015
# differential_evolution step 329: f(x)= 49.49698932806047
# differential_evolution step 330: f(x)= 49.49698932806047
# differential_evolution step 331: f(x)= 49.49698932806047
# differential_evolution step 332: f(x)= 49.49698932806047
# differential_evolution step 333: f(x)= 49.49698932806047
# differential_evolution step 334: f(x)= 49.49698932806047
# differential_evolution step 335: f(x)= 49.49698932806047
# differential_evolution step 336: f(x)= 49.49698932806047
# differential_evolution step 337: f(x)= 49.49698932806047
# differential_evolution step 338: f(x)= 49.4917338965028
# differential_evolution step 339: f(x)= 49.4917338965028
# differential_evolution step 340: f(x)= 49.48815912282697
# differential_evolution step 341: f(x)= 49.48815912282697
# differential_evolution step 342: f(x)= 49.48815912282697
# differential_evolution step 343: f(x)= 49.48815912282697
# differential_evolution step 344: f(x)= 49.48815912282697
# differential_evolution step 345: f(x)= 49.48815912282697
# differential_evolution step 346: f(x)= 49.48815912282697
# differential_evolution step 347: f(x)= 49.48815912282697
# differential_evolution step 348: f(x)= 49.48369568598085
# differential_evolution step 349: f(x)= 49.480936820132
# differential_evolution step 350: f(x)= 49.480936820132
# differential_evolution step 351: f(x)= 49.480936820132
# differential_evolution step 352: f(x)= 49.480936820132
# differential_evolution step 353: f(x)= 49.480936820132
# differential_evolution step 354: f(x)= 49.480936820132
# differential_evolution step 355: f(x)= 49.480936820132
# differential_evolution step 356: f(x)= 49.480936820132
# differential_evolution step 357: f(x)= 49.480936820132
# differential_evolution step 358: f(x)= 49.480936820132
# differential_evolution step 359: f(x)= 49.480936820132
# differential_evolution step 360: f(x)= 49.480936820132
# differential_evolution step 361: f(x)= 49.480936820132
# differential_evolution step 362: f(x)= 49.480936820132
# differential_evolution step 363: f(x)= 49.480936820132
# differential_evolution step 364: f(x)= 49.47911854998279
# differential_evolution step 365: f(x)= 49.47911854998279
# differential_evolution step 366: f(x)= 49.47911854998279
# differential_evolution step 367: f(x)= 49.47911854998279
# differential_evolution step 368: f(x)= 49.47911854998279
# differential_evolution step 369: f(x)= 49.478463208739996
# differential_evolution step 370: f(x)= 49.478463208739996
# differential_evolution step 371: f(x)= 49.478463208739996
# differential_evolution step 372: f(x)= 49.47820222760499
# differential_evolution step 373: f(x)= 49.47820222760499
# differential_evolution step 374: f(x)= 49.47820222760499
# differential_evolution step 375: f(x)= 49.47820222760499
# differential_evolution step 376: f(x)= 49.47820222760499
# differential_evolution step 377: f(x)= 49.47820222760499
# differential_evolution step 378: f(x)= 49.47820222760499
# differential_evolution step 379: f(x)= 49.47820222760499
# differential_evolution step 380: f(x)= 49.47783611193665
# differential_evolution step 381: f(x)= 49.47783611193665
# differential_evolution step 382: f(x)= 49.47783611193665
# differential_evolution step 383: f(x)= 49.47698351877438
# differential_evolution step 384: f(x)= 49.47698351877438
# differential_evolution step 385: f(x)= 49.47698351877438
# differential_evolution step 386: f(x)= 49.47698351877438
# differential_evolution step 387: f(x)= 49.47698351877438
# differential_evolution step 388: f(x)= 49.47698351877438
# differential_evolution step 389: f(x)= 49.47698351877438
# differential_evolution step 390: f(x)= 49.47661328579702
# differential_evolution step 391: f(x)= 49.47661328579702
# differential_evolution step 392: f(x)= 49.47612565627828
# differential_evolution step 393: f(x)= 49.47612565627828
# differential_evolution step 394: f(x)= 49.47612565627828
# differential_evolution step 395: f(x)= 49.47612565627828
# differential_evolution step 396: f(x)= 49.47612565627828
# differential_evolution step 397: f(x)= 49.47612565627828
# differential_evolution step 398: f(x)= 49.47612565627828
# differential_evolution step 399: f(x)= 49.47612565627828
# differential_evolution step 400: f(x)= 49.47612565627828
# differential_evolution step 401: f(x)= 49.47612565627828
# differential_evolution step 402: f(x)= 49.47612565627828
# differential_evolution step 403: f(x)= 49.47612565627828
# differential_evolution step 404: f(x)= 49.47612565627828
# differential_evolution step 405: f(x)= 49.47612565627828
# differential_evolution step 406: f(x)= 49.47612565627828
# differential_evolution step 407: f(x)= 49.47612565627828
# differential_evolution step 408: f(x)= 49.47612565627828
# differential_evolution step 409: f(x)= 49.47612565627828
# differential_evolution step 410: f(x)= 49.47612565627828
# differential_evolution step 411: f(x)= 49.47612565627828
# differential_evolution step 412: f(x)= 49.47550846929997
# differential_evolution step 413: f(x)= 49.47550846929997
# differential_evolution step 414: f(x)= 49.47550846929997
# differential_evolution step 415: f(x)= 49.47550846929997
# differential_evolution step 416: f(x)= 49.47550846929997
# differential_evolution step 417: f(x)= 49.47550846929997
# differential_evolution step 418: f(x)= 49.47550846929997
# differential_evolution step 419: f(x)= 49.47550846929997
# differential_evolution step 420: f(x)= 49.47550846929997
# differential_evolution step 421: f(x)= 49.47550846929997
# differential_evolution step 422: f(x)= 49.47550846929997
# differential_evolution step 423: f(x)= 49.47550846929997
# differential_evolution step 424: f(x)= 49.47531089589643
# differential_evolution step 425: f(x)= 49.47531089589643
# differential_evolution step 426: f(x)= 49.47531089589643
# differential_evolution step 427: f(x)= 49.475121899687686
# differential_evolution step 428: f(x)= 49.475121899687686
# differential_evolution step 429: f(x)= 49.475121899687686
# differential_evolution step 430: f(x)= 49.475121899687686
# differential_evolution step 431: f(x)= 49.475121899687686
# differential_evolution step 432: f(x)= 49.475121899687686
# differential_evolution step 433: f(x)= 49.475121899687686
# differential_evolution step 434: f(x)= 49.475121165182046
# differential_evolution step 435: f(x)= 49.475121165182046
# differential_evolution step 436: f(x)= 49.475121165182046
# differential_evolution step 437: f(x)= 49.474983496122746
# differential_evolution step 438: f(x)= 49.474983496122746
# differential_evolution step 439: f(x)= 49.474983496122746
# differential_evolution step 440: f(x)= 49.474983496122746
# differential_evolution step 441: f(x)= 49.474983496122746
# differential_evolution step 442: f(x)= 49.474983496122746
# differential_evolution step 443: f(x)= 49.47487007989137
# differential_evolution step 444: f(x)= 49.47475352083834
# differential_evolution step 445: f(x)= 49.47475352083834
# differential_evolution step 446: f(x)= 49.47473691063113
# differential_evolution step 447: f(x)= 49.47473691063113
# differential_evolution step 448: f(x)= 49.47473691063113
# differential_evolution step 449: f(x)= 49.47473691063113
# differential_evolution step 450: f(x)= 49.47473691063113
# differential_evolution step 451: f(x)= 49.47473691063113
# differential_evolution step 452: f(x)= 49.47473691063113
# differential_evolution step 453: f(x)= 49.47473691063113
# differential_evolution step 454: f(x)= 49.47473691063113
# differential_evolution step 455: f(x)= 49.47473691063113
# differential_evolution step 456: f(x)= 49.47473691063113
# differential_evolution step 457: f(x)= 49.47473691063113
# differential_evolution step 458: f(x)= 49.474623025522625
# differential_evolution step 459: f(x)= 49.474623025522625
# differential_evolution step 460: f(x)= 49.474623025522625
# differential_evolution step 461: f(x)= 49.474623025522625
# differential_evolution step 462: f(x)= 49.474623025522625
# differential_evolution step 463: f(x)= 49.474596286443614
# differential_evolution step 464: f(x)= 49.474596286443614
# differential_evolution step 465: f(x)= 49.474596286443614
# differential_evolution step 466: f(x)= 49.474596286443614
# differential_evolution step 467: f(x)= 49.474596286443614
# differential_evolution step 468: f(x)= 49.474596286443614
# differential_evolution step 469: f(x)= 49.474596286443614
# differential_evolution step 470: f(x)= 49.474596286443614
# differential_evolution step 471: f(x)= 49.474596286443614
# differential_evolution step 472: f(x)= 49.474596286443614
# differential_evolution step 473: f(x)= 49.474596286443614
# differential_evolution step 474: f(x)= 49.474564231583756
# differential_evolution step 475: f(x)= 49.474564231583756
# differential_evolution step 476: f(x)= 49.474564231583756
# differential_evolution step 477: f(x)= 49.474564231583756
# differential_evolution step 478: f(x)= 49.474528960297334
# differential_evolution step 479: f(x)= 49.474528960297334
# differential_evolution step 480: f(x)= 49.474528960297334
# differential_evolution step 481: f(x)= 49.474528960297334
# differential_evolution step 482: f(x)= 49.474528960297334
# differential_evolution step 483: f(x)= 49.474528960297334
# differential_evolution step 484: f(x)= 49.474512627742826
# differential_evolution step 485: f(x)= 49.474512627742826
# differential_evolution step 486: f(x)= 49.474512627742826
# differential_evolution step 487: f(x)= 49.474512627742826
# differential_evolution step 488: f(x)= 49.474512627742826
# differential_evolution step 489: f(x)= 49.474512627742826
# differential_evolution step 490: f(x)= 49.474512627742826
# differential_evolution step 491: f(x)= 49.474512627742826
# differential_evolution step 492: f(x)= 49.474512627742826
# differential_evolution step 493: f(x)= 49.474512627742826
# differential_evolution step 494: f(x)= 49.474512627742826
# differential_evolution step 495: f(x)= 49.47449918026807
# differential_evolution step 496: f(x)= 49.47449918026807
# differential_evolution step 497: f(x)= 49.47449918026807
# differential_evolution step 498: f(x)= 49.47449918026807
# differential_evolution step 499: f(x)= 49.47449485368261
# differential_evolution step 500: f(x)= 49.47449485368261
# differential_evolution step 501: f(x)= 49.47447635857667
# differential_evolution step 502: f(x)= 49.47447635857667
# differential_evolution step 503: f(x)= 49.47446531388223
# differential_evolution step 504: f(x)= 49.47446531388223
# differential_evolution step 505: f(x)= 49.47446531388223
# differential_evolution step 506: f(x)= 49.47446531388223
# differential_evolution step 507: f(x)= 49.47446531388223
# differential_evolution step 508: f(x)= 49.47446087223168
# differential_evolution step 509: f(x)= 49.47446087223168
# differential_evolution step 510: f(x)= 49.47446087223168
# differential_evolution step 511: f(x)= 49.47446087223168
# differential_evolution step 512: f(x)= 49.474447318272325
# differential_evolution step 513: f(x)= 49.474447318272325
# differential_evolution step 514: f(x)= 49.474447318272325
# differential_evolution step 515: f(x)= 49.474447318272325
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=10.5552, n=2.3044, x_0=39.7444
# Sérsic 2: I_e=1.0000, r_e=8.9192, n=1.0581, x_0=43.6216
# Sérsic 3: I_e=0.6689, r_e=9.4435, n=1.3168, x_0=57.9312
# Chi quadro minimo: 49.47441347545785
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HB, r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_HB, covariance_HB = curve_fit(model_convolved, x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB)

chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, radial_profile_error_HB,
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:511: RuntimeWarning: invalid value encountered in multiply
#   ret = ifft(sp1 * sp2, fshape, axes=axes)
# Sérsic 1: I_e=3.3818, r_e=4.7987, n=1.3308, x_0=39.8423
# Sérsic 2: I_e=1.5986, r_e=7.6671, n=0.0441, x_0=44.5744
# Sérsic 3: I_e=1.0185, r_e=6.8824, n=1.1772, x_0=58.1523
# [0.44834977 0.35952136 0.10353458 0.05685355 3.80995661 0.82314649
#  0.05232055 0.20140901 0.20570585 0.97225464 0.14283868 0.10843651]
# 21.19363925579504

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 920.2300545336338
# differential_evolution step 2: f(x)= 630.5108395912315
# differential_evolution step 3: f(x)= 494.59207636288374
# differential_evolution step 4: f(x)= 494.59207636288374
# differential_evolution step 5: f(x)= 494.59207636288374
# differential_evolution step 6: f(x)= 494.59207636288374
# differential_evolution step 7: f(x)= 494.59207636288374
# differential_evolution step 8: f(x)= 494.59207636288374
# differential_evolution step 9: f(x)= 430.7192550181591
# differential_evolution step 10: f(x)= 430.7192550181591
# differential_evolution step 11: f(x)= 430.7192550181591
# differential_evolution step 12: f(x)= 430.7192550181591
# differential_evolution step 13: f(x)= 430.7192550181591
# differential_evolution step 14: f(x)= 410.80526319000614
# differential_evolution step 15: f(x)= 410.80526319000614
# differential_evolution step 16: f(x)= 359.95615725576295
# differential_evolution step 17: f(x)= 359.95615725576295
# differential_evolution step 18: f(x)= 359.95615725576295
# differential_evolution step 19: f(x)= 359.95615725576295
# differential_evolution step 20: f(x)= 359.95615725576295
# differential_evolution step 21: f(x)= 359.95615725576295
# differential_evolution step 22: f(x)= 359.95615725576295
# differential_evolution step 23: f(x)= 359.95615725576295
# differential_evolution step 24: f(x)= 359.95615725576295
# differential_evolution step 25: f(x)= 359.95615725576295
# differential_evolution step 26: f(x)= 356.0468175640287
# differential_evolution step 27: f(x)= 348.5450017146259
# differential_evolution step 28: f(x)= 348.5450017146259
# differential_evolution step 29: f(x)= 348.5450017146259
# differential_evolution step 30: f(x)= 338.4021546168976
# differential_evolution step 31: f(x)= 338.4021546168976
# differential_evolution step 32: f(x)= 338.4021546168976
# differential_evolution step 33: f(x)= 338.4021546168976
# differential_evolution step 34: f(x)= 338.4021546168976
# differential_evolution step 35: f(x)= 338.4021546168976
# differential_evolution step 36: f(x)= 335.0489359685628
# differential_evolution step 37: f(x)= 326.7380998218245
# differential_evolution step 38: f(x)= 321.25732940119315
# differential_evolution step 39: f(x)= 321.25732940119315
# differential_evolution step 40: f(x)= 321.25732940119315
# differential_evolution step 41: f(x)= 321.25732940119315
# differential_evolution step 42: f(x)= 321.25732940119315
# differential_evolution step 43: f(x)= 321.25732940119315
# differential_evolution step 44: f(x)= 321.25732940119315
# differential_evolution step 45: f(x)= 318.91701094716996
# differential_evolution step 46: f(x)= 318.91701094716996
# differential_evolution step 47: f(x)= 317.67893581540847
# differential_evolution step 48: f(x)= 317.67893581540847
# differential_evolution step 49: f(x)= 317.67893581540847
# differential_evolution step 50: f(x)= 317.67893581540847
# differential_evolution step 51: f(x)= 317.67893581540847
# differential_evolution step 52: f(x)= 317.67893581540847
# differential_evolution step 53: f(x)= 314.99357322091464
# differential_evolution step 54: f(x)= 303.31856755462917
# differential_evolution step 55: f(x)= 303.31856755462917
# differential_evolution step 56: f(x)= 303.31856755462917
# differential_evolution step 57: f(x)= 298.476662666009
# differential_evolution step 58: f(x)= 298.476662666009
# differential_evolution step 59: f(x)= 298.476662666009
# differential_evolution step 60: f(x)= 298.476662666009
# differential_evolution step 61: f(x)= 298.476662666009
# differential_evolution step 62: f(x)= 298.476662666009
# differential_evolution step 63: f(x)= 298.476662666009
# differential_evolution step 64: f(x)= 298.476662666009
# differential_evolution step 65: f(x)= 298.476662666009
# differential_evolution step 66: f(x)= 298.476662666009
# differential_evolution step 67: f(x)= 298.476662666009
# differential_evolution step 68: f(x)= 298.476662666009
# differential_evolution step 69: f(x)= 298.476662666009
# differential_evolution step 70: f(x)= 298.476662666009
# differential_evolution step 71: f(x)= 293.2499783451128
# differential_evolution step 72: f(x)= 293.2499783451128
# differential_evolution step 73: f(x)= 292.5827073884274
# differential_evolution step 74: f(x)= 292.5827073884274
# differential_evolution step 75: f(x)= 292.5827073884274
# differential_evolution step 76: f(x)= 292.57407340853314
# differential_evolution step 77: f(x)= 292.57407340853314
# differential_evolution step 78: f(x)= 292.57407340853314
# differential_evolution step 79: f(x)= 292.57407340853314
# differential_evolution step 80: f(x)= 292.57407340853314
# differential_evolution step 81: f(x)= 292.57407340853314
# differential_evolution step 82: f(x)= 291.832436277634
# differential_evolution step 83: f(x)= 291.1954724007039
# differential_evolution step 84: f(x)= 291.1954724007039
# differential_evolution step 85: f(x)= 291.1954724007039
# differential_evolution step 86: f(x)= 291.1954724007039
# differential_evolution step 87: f(x)= 286.616319916452
# differential_evolution step 88: f(x)= 286.616319916452
# differential_evolution step 89: f(x)= 286.616319916452
# differential_evolution step 90: f(x)= 286.616319916452
# differential_evolution step 91: f(x)= 284.5368232087337
# differential_evolution step 92: f(x)= 284.5368232087337
# differential_evolution step 93: f(x)= 284.5368232087337
# differential_evolution step 94: f(x)= 284.5368232087337
# differential_evolution step 95: f(x)= 284.5368232087337
# differential_evolution step 96: f(x)= 284.5368232087337
# differential_evolution step 97: f(x)= 284.5368232087337
# differential_evolution step 98: f(x)= 284.5368232087337
# differential_evolution step 99: f(x)= 284.5368232087337
# differential_evolution step 100: f(x)= 284.5368232087337
# differential_evolution step 101: f(x)= 284.5368232087337
# differential_evolution step 102: f(x)= 284.5368232087337
# differential_evolution step 103: f(x)= 284.5368232087337
# differential_evolution step 104: f(x)= 284.18682117647097
# differential_evolution step 105: f(x)= 284.18682117647097
# differential_evolution step 106: f(x)= 284.18682117647097
# differential_evolution step 107: f(x)= 284.18682117647097
# differential_evolution step 108: f(x)= 284.16033784188187
# differential_evolution step 109: f(x)= 284.16033784188187
# differential_evolution step 110: f(x)= 281.29082456265576
# differential_evolution step 111: f(x)= 281.29082456265576
# differential_evolution step 112: f(x)= 280.13496280346146
# differential_evolution step 113: f(x)= 280.13496280346146
# differential_evolution step 114: f(x)= 280.13496280346146
# differential_evolution step 115: f(x)= 280.13496280346146
# differential_evolution step 116: f(x)= 280.13496280346146
# differential_evolution step 117: f(x)= 280.13496280346146
# differential_evolution step 118: f(x)= 280.13496280346146
# differential_evolution step 119: f(x)= 280.0131267985964
# differential_evolution step 120: f(x)= 280.0131267985964
# differential_evolution step 121: f(x)= 279.1064802910414
# differential_evolution step 122: f(x)= 278.7115747059322
# differential_evolution step 123: f(x)= 278.7115747059322
# differential_evolution step 124: f(x)= 278.7115747059322
# differential_evolution step 125: f(x)= 278.7115747059322
# differential_evolution step 126: f(x)= 278.7115747059322
# differential_evolution step 127: f(x)= 278.7115747059322
# differential_evolution step 128: f(x)= 278.7115747059322
# differential_evolution step 129: f(x)= 278.1571639677388
# differential_evolution step 130: f(x)= 278.1322007049743
# differential_evolution step 131: f(x)= 277.54582567099527
# differential_evolution step 132: f(x)= 277.3736330279453
# differential_evolution step 133: f(x)= 277.20600845807473
# differential_evolution step 134: f(x)= 277.20600845807473
# differential_evolution step 135: f(x)= 277.20600845807473
# differential_evolution step 136: f(x)= 277.099951391383
# differential_evolution step 137: f(x)= 277.098390387737
# differential_evolution step 138: f(x)= 277.098390387737
# differential_evolution step 139: f(x)= 277.0980438291629
# differential_evolution step 140: f(x)= 277.0980438291629
# differential_evolution step 141: f(x)= 276.8083812408544
# differential_evolution step 142: f(x)= 276.6095221415708
# differential_evolution step 143: f(x)= 276.2896420287226
# differential_evolution step 144: f(x)= 276.2896420287226
# differential_evolution step 145: f(x)= 276.2896420287226
# differential_evolution step 146: f(x)= 276.2896420287226
# differential_evolution step 147: f(x)= 276.2896420287226
# differential_evolution step 148: f(x)= 276.2896420287226
# differential_evolution step 149: f(x)= 276.2896420287226
# differential_evolution step 150: f(x)= 276.2896420287226
# differential_evolution step 151: f(x)= 276.25890440905954
# differential_evolution step 152: f(x)= 276.25890440905954
# differential_evolution step 153: f(x)= 276.25890440905954
# differential_evolution step 154: f(x)= 275.84088975771226
# differential_evolution step 155: f(x)= 275.84088975771226
# differential_evolution step 156: f(x)= 275.84088975771226
# differential_evolution step 157: f(x)= 275.7949331937494
# differential_evolution step 158: f(x)= 275.7949331937494
# differential_evolution step 159: f(x)= 275.6659973887931
# differential_evolution step 160: f(x)= 275.6659973887931
# differential_evolution step 161: f(x)= 275.6659973887931
# differential_evolution step 162: f(x)= 275.6659973887931
# differential_evolution step 163: f(x)= 275.6659973887931
# differential_evolution step 164: f(x)= 275.6659973887931
# differential_evolution step 165: f(x)= 275.6659973887931
# differential_evolution step 166: f(x)= 275.53737863590237
# differential_evolution step 167: f(x)= 275.37500818558925
# differential_evolution step 168: f(x)= 275.37500818558925
# differential_evolution step 169: f(x)= 275.37500818558925
# differential_evolution step 170: f(x)= 275.32312852983205
# differential_evolution step 171: f(x)= 275.32312852983205
# differential_evolution step 172: f(x)= 275.32312852983205
# differential_evolution step 173: f(x)= 275.32312852983205
# differential_evolution step 174: f(x)= 275.32312852983205
# differential_evolution step 175: f(x)= 275.32312852983205
# differential_evolution step 176: f(x)= 275.2384113845469
# differential_evolution step 177: f(x)= 275.2384113845469
# differential_evolution step 178: f(x)= 275.2384113845469
# differential_evolution step 179: f(x)= 275.2384113845469
# differential_evolution step 180: f(x)= 275.2258695588961
# differential_evolution step 181: f(x)= 275.221104062255
# differential_evolution step 182: f(x)= 275.221104062255
# differential_evolution step 183: f(x)= 275.221104062255
# differential_evolution step 184: f(x)= 275.1589534083853
# differential_evolution step 185: f(x)= 275.14639631098163
# differential_evolution step 186: f(x)= 275.14639631098163
# differential_evolution step 187: f(x)= 275.14639631098163
# differential_evolution step 188: f(x)= 275.1127707449214
# differential_evolution step 189: f(x)= 275.1127707449214
# differential_evolution step 190: f(x)= 275.1127707449214
# differential_evolution step 191: f(x)= 275.1127707449214
# differential_evolution step 192: f(x)= 275.0945358331717
# differential_evolution step 193: f(x)= 275.0564336982953
# differential_evolution step 194: f(x)= 275.0564336982953
# differential_evolution step 195: f(x)= 275.0564336982953
# differential_evolution step 196: f(x)= 275.0564336982953
# differential_evolution step 197: f(x)= 275.0564336982953
# differential_evolution step 198: f(x)= 275.054179550101
# differential_evolution step 199: f(x)= 275.0490069532574
# differential_evolution step 200: f(x)= 275.03469031722096
# differential_evolution step 201: f(x)= 275.03469031722096
# differential_evolution step 202: f(x)= 275.03469031722096
# differential_evolution step 203: f(x)= 275.03256283667895
# differential_evolution step 204: f(x)= 275.03256283667895
# differential_evolution step 205: f(x)= 275.03256283667895
# differential_evolution step 206: f(x)= 275.03256283667895
# differential_evolution step 207: f(x)= 275.03256283667895
# differential_evolution step 208: f(x)= 275.014382869682
# differential_evolution step 209: f(x)= 275.014382869682
# differential_evolution step 210: f(x)= 274.99362860720686
# differential_evolution step 211: f(x)= 274.99362860720686
# differential_evolution step 212: f(x)= 274.99362860720686
# differential_evolution step 213: f(x)= 274.98163634131174
# differential_evolution step 214: f(x)= 274.98163634131174
# differential_evolution step 215: f(x)= 274.98163634131174
# differential_evolution step 216: f(x)= 274.98163634131174
# differential_evolution step 217: f(x)= 274.98163634131174
# differential_evolution step 218: f(x)= 274.98163634131174
# differential_evolution step 219: f(x)= 274.98163634131174
# differential_evolution step 220: f(x)= 274.97870894985067
# differential_evolution step 221: f(x)= 274.97870894985067
# differential_evolution step 222: f(x)= 274.97870894985067
# differential_evolution step 223: f(x)= 274.97870894985067
# differential_evolution step 224: f(x)= 274.97668919948256
# differential_evolution step 225: f(x)= 274.97668919948256
# differential_evolution step 226: f(x)= 274.97668919948256
# differential_evolution step 227: f(x)= 274.97668919948256
# differential_evolution step 228: f(x)= 274.97668919948256
# differential_evolution step 229: f(x)= 274.97668919948256
# differential_evolution step 230: f(x)= 274.9745302609958
# differential_evolution step 231: f(x)= 274.9745302609958
# differential_evolution step 232: f(x)= 274.97346622491204
# differential_evolution step 233: f(x)= 274.97346622491204
# differential_evolution step 234: f(x)= 274.9730889069676
# differential_evolution step 235: f(x)= 274.9730889069676
# differential_evolution step 236: f(x)= 274.9730889069676
# differential_evolution step 237: f(x)= 274.9730889069676
# differential_evolution step 238: f(x)= 274.97303304572915
# differential_evolution step 239: f(x)= 274.96975865535336
# differential_evolution step 240: f(x)= 274.96956266536654
# differential_evolution step 241: f(x)= 274.96956266536654
# differential_evolution step 242: f(x)= 274.96956266536654
# differential_evolution step 243: f(x)= 274.96956266536654
# differential_evolution step 244: f(x)= 274.96956266536654
# differential_evolution step 245: f(x)= 274.96956266536654
# differential_evolution step 246: f(x)= 274.96956266536654
# differential_evolution step 247: f(x)= 274.9673247682679
# differential_evolution step 248: f(x)= 274.9673247682679
# differential_evolution step 249: f(x)= 274.9673247682679
# differential_evolution step 250: f(x)= 274.9673247682679
# differential_evolution step 251: f(x)= 274.9673247682679
# differential_evolution step 252: f(x)= 274.9673247682679
# differential_evolution step 253: f(x)= 274.9673247682679
# differential_evolution step 254: f(x)= 274.9673247682679
# differential_evolution step 255: f(x)= 274.9673247682679
# differential_evolution step 256: f(x)= 274.9673247682679
# differential_evolution step 257: f(x)= 274.9673247682679
# differential_evolution step 258: f(x)= 274.9672312720615
# differential_evolution step 259: f(x)= 274.9672312720615
# differential_evolution step 260: f(x)= 274.9672312720615
# differential_evolution step 261: f(x)= 274.9672312720615
# differential_evolution step 262: f(x)= 274.9672312720615
# differential_evolution step 263: f(x)= 274.9672312720615
# differential_evolution step 264: f(x)= 274.96702297714086
# differential_evolution step 265: f(x)= 274.96702297714086
# differential_evolution step 266: f(x)= 274.9664453975055
# differential_evolution step 267: f(x)= 274.9664453975055
# differential_evolution step 268: f(x)= 274.9664453975055
# differential_evolution step 269: f(x)= 274.9664453975055
# differential_evolution step 270: f(x)= 274.9664453975055
# differential_evolution step 271: f(x)= 274.9664453975055
# differential_evolution step 272: f(x)= 274.9658338341064
# differential_evolution step 273: f(x)= 274.9658338341064
# differential_evolution step 274: f(x)= 274.9658338341064
# differential_evolution step 275: f(x)= 274.9654180545693
# differential_evolution step 276: f(x)= 274.9654180545693
# differential_evolution step 277: f(x)= 274.9654180545693
# differential_evolution step 278: f(x)= 274.9654180545693
# differential_evolution step 279: f(x)= 274.965146082225
# differential_evolution step 280: f(x)= 274.965146082225
# differential_evolution step 281: f(x)= 274.965146082225
# differential_evolution step 282: f(x)= 274.965146082225
# differential_evolution step 283: f(x)= 274.965146082225
# differential_evolution step 284: f(x)= 274.965146082225
# differential_evolution step 285: f(x)= 274.965146082225
# differential_evolution step 286: f(x)= 274.965146082225
# differential_evolution step 287: f(x)= 274.965146082225
# differential_evolution step 288: f(x)= 274.9651191332748
# differential_evolution step 289: f(x)= 274.9651191332748
# differential_evolution step 290: f(x)= 274.9651191332748
# differential_evolution step 291: f(x)= 274.9651191332748
# differential_evolution step 292: f(x)= 274.9651191332748
# differential_evolution step 293: f(x)= 274.96502356254507
# differential_evolution step 294: f(x)= 274.96502356254507
# differential_evolution step 295: f(x)= 274.9650114133072
# differential_evolution step 296: f(x)= 274.9650114133072
# differential_evolution step 297: f(x)= 274.9650114133072
# differential_evolution step 298: f(x)= 274.96454791772203
# differential_evolution step 299: f(x)= 274.96454791772203
# differential_evolution step 300: f(x)= 274.96454791772203
# differential_evolution step 301: f(x)= 274.96454791772203
# differential_evolution step 302: f(x)= 274.96454791772203
# differential_evolution step 303: f(x)= 274.96454791772203
# differential_evolution step 304: f(x)= 274.96454791772203
# differential_evolution step 305: f(x)= 274.96454791772203
# differential_evolution step 306: f(x)= 274.96454791772203
# differential_evolution step 307: f(x)= 274.96454791772203
# differential_evolution step 308: f(x)= 274.96454791772203
# differential_evolution step 309: f(x)= 274.96454791772203
# differential_evolution step 310: f(x)= 274.96454791772203
# differential_evolution step 311: f(x)= 274.96454791772203
# differential_evolution step 312: f(x)= 274.96454791772203
# differential_evolution step 313: f(x)= 274.96454791772203
# differential_evolution step 314: f(x)= 274.96454791772203
# differential_evolution step 315: f(x)= 274.96454791772203
# differential_evolution step 316: f(x)= 274.96454791772203
# differential_evolution step 317: f(x)= 274.96454791772203
# differential_evolution step 318: f(x)= 274.9644428370009
# differential_evolution step 319: f(x)= 274.9644428370009
# differential_evolution step 320: f(x)= 274.9644428370009
# differential_evolution step 321: f(x)= 274.9644428370009
# differential_evolution step 322: f(x)= 274.9644428370009
# differential_evolution step 323: f(x)= 274.9644428370009
# differential_evolution step 324: f(x)= 274.9644428370009
# differential_evolution step 325: f(x)= 274.9644428370009
# differential_evolution step 326: f(x)= 274.9644259499924
# differential_evolution step 327: f(x)= 274.9644259499924
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=16.3270, n=2.8494, x_0=39.3247
# Sérsic 2: I_e=1.0000, r_e=10.1676, n=1.3444, x_0=43.6216
# Sérsic 3: I_e=1.0000, r_e=9.1174, n=1.2024, x_0=56.5431
# Chi quadro minimo: 274.9641487302026
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII, r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(model_convolved, x_axes, radial_profile_NII, p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)

chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII,
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Sérsic 1: I_e=1.0000, r_e=10.8224, n=3.1957, x_0=39.2765
# Sérsic 2: I_e=1.0000, r_e=10.5352, n=1.5564, x_0=43.6216
# Sérsic 3: I_e=1.0000, r_e=8.5319, n=1.2747, x_0=56.4204
# [ 3.80793115 31.78639327  2.95140074  0.09119068  2.53993254 29.78113722
#   1.72843625  0.58829471  0.66115154  4.9688666   0.47941769  0.48158661]
# 615.3642585947265

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 295.95217292298156
# differential_evolution step 2: f(x)= 232.17968527150748
# differential_evolution step 3: f(x)= 190.67144017185328
# differential_evolution step 4: f(x)= 121.0686284655212
# differential_evolution step 5: f(x)= 121.0686284655212
# differential_evolution step 6: f(x)= 121.0686284655212
# differential_evolution step 7: f(x)= 121.0686284655212
# differential_evolution step 8: f(x)= 121.0686284655212
# differential_evolution step 9: f(x)= 121.0686284655212
# differential_evolution step 10: f(x)= 121.0686284655212
# differential_evolution step 11: f(x)= 121.0686284655212
# differential_evolution step 12: f(x)= 95.52875393510612
# differential_evolution step 13: f(x)= 95.52875393510612
# differential_evolution step 14: f(x)= 95.52875393510612
# differential_evolution step 15: f(x)= 95.52875393510612
# differential_evolution step 16: f(x)= 95.52875393510612
# differential_evolution step 17: f(x)= 95.52875393510612
# differential_evolution step 18: f(x)= 95.52875393510612
# differential_evolution step 19: f(x)= 95.52875393510612
# differential_evolution step 20: f(x)= 95.52875393510612
# differential_evolution step 21: f(x)= 95.52875393510612
# differential_evolution step 22: f(x)= 95.52875393510612
# differential_evolution step 23: f(x)= 83.06056778132816
# differential_evolution step 24: f(x)= 83.06056778132816
# differential_evolution step 25: f(x)= 83.06056778132816
# differential_evolution step 26: f(x)= 83.06056778132816
# differential_evolution step 27: f(x)= 83.06056778132816
# differential_evolution step 28: f(x)= 81.79883863641169
# differential_evolution step 29: f(x)= 81.79883863641169
# differential_evolution step 30: f(x)= 81.79883863641169
# differential_evolution step 31: f(x)= 81.79883863641169
# differential_evolution step 32: f(x)= 81.79883863641169
# differential_evolution step 33: f(x)= 81.79883863641169
# differential_evolution step 34: f(x)= 81.79883863641169
# differential_evolution step 35: f(x)= 81.79883863641169
# differential_evolution step 36: f(x)= 81.63916789945516
# differential_evolution step 37: f(x)= 75.98786081840305
# differential_evolution step 38: f(x)= 75.98786081840305
# differential_evolution step 39: f(x)= 75.98786081840305
# differential_evolution step 40: f(x)= 75.98786081840305
# differential_evolution step 41: f(x)= 75.98786081840305
# differential_evolution step 42: f(x)= 75.98786081840305
# differential_evolution step 43: f(x)= 75.98786081840305
# differential_evolution step 44: f(x)= 75.98786081840305
# differential_evolution step 45: f(x)= 75.98786081840305
# differential_evolution step 46: f(x)= 74.27936526796104
# differential_evolution step 47: f(x)= 74.27936526796104
# differential_evolution step 48: f(x)= 74.27936526796104
# differential_evolution step 49: f(x)= 71.73174391384649
# differential_evolution step 50: f(x)= 71.73174391384649
# differential_evolution step 51: f(x)= 71.73174391384649
# differential_evolution step 52: f(x)= 71.73174391384649
# differential_evolution step 53: f(x)= 70.88141193539937
# differential_evolution step 54: f(x)= 70.88141193539937
# differential_evolution step 55: f(x)= 70.88141193539937
# differential_evolution step 56: f(x)= 70.88141193539937
# differential_evolution step 57: f(x)= 70.88141193539937
# differential_evolution step 58: f(x)= 70.88141193539937
# differential_evolution step 59: f(x)= 70.88141193539937
# differential_evolution step 60: f(x)= 70.88141193539937
# differential_evolution step 61: f(x)= 70.88141193539937
# differential_evolution step 62: f(x)= 70.88141193539937
# differential_evolution step 63: f(x)= 70.88141193539937
# differential_evolution step 64: f(x)= 70.88141193539937
# differential_evolution step 65: f(x)= 68.87591903596972
# differential_evolution step 66: f(x)= 68.87591903596972
# differential_evolution step 67: f(x)= 68.87591903596972
# differential_evolution step 68: f(x)= 68.22165606051534
# differential_evolution step 69: f(x)= 68.22165606051534
# differential_evolution step 70: f(x)= 68.22165606051534
# differential_evolution step 71: f(x)= 68.22165606051534
# differential_evolution step 72: f(x)= 68.22165606051534
# differential_evolution step 73: f(x)= 68.22165606051534
# differential_evolution step 74: f(x)= 68.22165606051534
# differential_evolution step 75: f(x)= 68.22165606051534
# differential_evolution step 76: f(x)= 67.97004089983575
# differential_evolution step 77: f(x)= 67.97004089983575
# differential_evolution step 78: f(x)= 67.97004089983575
# differential_evolution step 79: f(x)= 67.97004089983575
# differential_evolution step 80: f(x)= 66.86014174178264
# differential_evolution step 81: f(x)= 65.48447113491133
# differential_evolution step 82: f(x)= 65.48447113491133
# differential_evolution step 83: f(x)= 62.178762038156954
# differential_evolution step 84: f(x)= 62.178762038156954
# differential_evolution step 85: f(x)= 62.178762038156954
# differential_evolution step 86: f(x)= 62.178762038156954
# differential_evolution step 87: f(x)= 58.883117669312995
# differential_evolution step 88: f(x)= 58.48604213297526
# differential_evolution step 89: f(x)= 58.48604213297526
# differential_evolution step 90: f(x)= 58.48604213297526
# differential_evolution step 91: f(x)= 58.48604213297526
# differential_evolution step 92: f(x)= 58.48604213297526
# differential_evolution step 93: f(x)= 58.48604213297526
# differential_evolution step 94: f(x)= 58.48604213297526
# differential_evolution step 95: f(x)= 58.48604213297526
# differential_evolution step 96: f(x)= 57.097455133599944
# differential_evolution step 97: f(x)= 55.634009609462524
# differential_evolution step 98: f(x)= 55.634009609462524
# differential_evolution step 99: f(x)= 55.634009609462524
# differential_evolution step 100: f(x)= 55.634009609462524
# differential_evolution step 101: f(x)= 55.634009609462524
# differential_evolution step 102: f(x)= 55.634009609462524
# differential_evolution step 103: f(x)= 55.634009609462524
# differential_evolution step 104: f(x)= 55.634009609462524
# differential_evolution step 105: f(x)= 55.634009609462524
# differential_evolution step 106: f(x)= 55.634009609462524
# differential_evolution step 107: f(x)= 55.4826336911476
# differential_evolution step 108: f(x)= 55.4826336911476
# differential_evolution step 109: f(x)= 55.4826336911476
# differential_evolution step 110: f(x)= 55.4826336911476
# differential_evolution step 111: f(x)= 55.4826336911476
# differential_evolution step 112: f(x)= 55.4826336911476
# differential_evolution step 113: f(x)= 55.4826336911476
# differential_evolution step 114: f(x)= 55.38658389577673
# differential_evolution step 115: f(x)= 55.38658389577673
# differential_evolution step 116: f(x)= 55.38658389577673
# differential_evolution step 117: f(x)= 55.38658389577673
# differential_evolution step 118: f(x)= 55.286591050771804
# differential_evolution step 119: f(x)= 55.286591050771804
# differential_evolution step 120: f(x)= 55.286591050771804
# differential_evolution step 121: f(x)= 55.07119052128739
# differential_evolution step 122: f(x)= 54.76101183757826
# differential_evolution step 123: f(x)= 54.76101183757826
# differential_evolution step 124: f(x)= 54.76101183757826
# differential_evolution step 125: f(x)= 54.749779703010596
# differential_evolution step 126: f(x)= 54.749779703010596
# differential_evolution step 127: f(x)= 54.50511378355355
# differential_evolution step 128: f(x)= 54.50511378355355
# differential_evolution step 129: f(x)= 54.40194716111252
# differential_evolution step 130: f(x)= 54.40194716111252
# differential_evolution step 131: f(x)= 54.18538654022916
# differential_evolution step 132: f(x)= 54.18538654022916
# differential_evolution step 133: f(x)= 54.18538654022916
# differential_evolution step 134: f(x)= 54.18538654022916
# differential_evolution step 135: f(x)= 54.18538654022916
# differential_evolution step 136: f(x)= 54.18538654022916
# differential_evolution step 137: f(x)= 54.18538654022916
# differential_evolution step 138: f(x)= 54.18538654022916
# differential_evolution step 139: f(x)= 54.18538654022916
# differential_evolution step 140: f(x)= 54.18538654022916
# differential_evolution step 141: f(x)= 54.18538654022916
# differential_evolution step 142: f(x)= 54.000530996466
# differential_evolution step 143: f(x)= 54.000530996466
# differential_evolution step 144: f(x)= 53.959980984457935
# differential_evolution step 145: f(x)= 53.959980984457935
# differential_evolution step 146: f(x)= 53.959980984457935
# differential_evolution step 147: f(x)= 53.952391658059994
# differential_evolution step 148: f(x)= 53.952391658059994
# differential_evolution step 149: f(x)= 53.952391658059994
# differential_evolution step 150: f(x)= 53.952391658059994
# differential_evolution step 151: f(x)= 53.952391658059994
# differential_evolution step 152: f(x)= 53.952391658059994
# differential_evolution step 153: f(x)= 53.952391658059994
# differential_evolution step 154: f(x)= 53.952391658059994
# differential_evolution step 155: f(x)= 53.952391658059994
# differential_evolution step 156: f(x)= 53.952391658059994
# differential_evolution step 157: f(x)= 53.952391658059994
# differential_evolution step 158: f(x)= 53.952391658059994
# differential_evolution step 159: f(x)= 53.86139500369005
# differential_evolution step 160: f(x)= 53.86139500369005
# differential_evolution step 161: f(x)= 53.80643268028783
# differential_evolution step 162: f(x)= 53.80643268028783
# differential_evolution step 163: f(x)= 53.68332019423186
# differential_evolution step 164: f(x)= 53.68332019423186
# differential_evolution step 165: f(x)= 53.68332019423186
# differential_evolution step 166: f(x)= 53.68332019423186
# differential_evolution step 167: f(x)= 53.68332019423186
# differential_evolution step 168: f(x)= 53.68332019423186
# differential_evolution step 169: f(x)= 53.68332019423186
# differential_evolution step 170: f(x)= 53.61349891003154
# differential_evolution step 171: f(x)= 53.61349891003154
# differential_evolution step 172: f(x)= 53.592570030653214
# differential_evolution step 173: f(x)= 53.55453259163329
# differential_evolution step 174: f(x)= 53.55453259163329
# differential_evolution step 175: f(x)= 53.51227951872599
# differential_evolution step 176: f(x)= 53.51227951872599
# differential_evolution step 177: f(x)= 53.51227951872599
# differential_evolution step 178: f(x)= 53.51227951872599
# differential_evolution step 179: f(x)= 53.51227951872599
# differential_evolution step 180: f(x)= 53.51227951872599
# differential_evolution step 181: f(x)= 53.485284530185595
# differential_evolution step 182: f(x)= 53.485284530185595
# differential_evolution step 183: f(x)= 53.485284530185595
# differential_evolution step 184: f(x)= 53.485284530185595
# differential_evolution step 185: f(x)= 53.485284530185595
# differential_evolution step 186: f(x)= 53.485284530185595
# differential_evolution step 187: f(x)= 53.485284530185595
# differential_evolution step 188: f(x)= 53.485284530185595
# differential_evolution step 189: f(x)= 53.485284530185595
# differential_evolution step 190: f(x)= 53.485284530185595
# differential_evolution step 191: f(x)= 53.44822953513384
# differential_evolution step 192: f(x)= 53.44822953513384
# differential_evolution step 193: f(x)= 53.44822953513384
# differential_evolution step 194: f(x)= 53.44822953513384
# differential_evolution step 195: f(x)= 53.44822953513384
# differential_evolution step 196: f(x)= 53.44822953513384
# differential_evolution step 197: f(x)= 53.44822953513384
# differential_evolution step 198: f(x)= 53.44822953513384
# differential_evolution step 199: f(x)= 53.44822953513384
# differential_evolution step 200: f(x)= 53.44822953513384
# differential_evolution step 201: f(x)= 53.44822953513384
# differential_evolution step 202: f(x)= 53.44822953513384
# differential_evolution step 203: f(x)= 53.41931351397987
# differential_evolution step 204: f(x)= 53.383906234657616
# differential_evolution step 205: f(x)= 53.383906234657616
# differential_evolution step 206: f(x)= 53.383906234657616
# differential_evolution step 207: f(x)= 53.383906234657616
# differential_evolution step 208: f(x)= 53.383906234657616
# differential_evolution step 209: f(x)= 53.383906234657616
# differential_evolution step 210: f(x)= 53.383906234657616
# differential_evolution step 211: f(x)= 53.383906234657616
# differential_evolution step 212: f(x)= 53.383906234657616
# differential_evolution step 213: f(x)= 53.37204641130973
# differential_evolution step 214: f(x)= 53.35335693324906
# differential_evolution step 215: f(x)= 53.35335693324906
# differential_evolution step 216: f(x)= 53.35335693324906
# differential_evolution step 217: f(x)= 53.339789867786486
# differential_evolution step 218: f(x)= 53.339789867786486
# differential_evolution step 219: f(x)= 53.339789867786486
# differential_evolution step 220: f(x)= 53.339789867786486
# differential_evolution step 221: f(x)= 53.339789867786486
# differential_evolution step 222: f(x)= 53.339789867786486
# differential_evolution step 223: f(x)= 53.339789867786486
# differential_evolution step 224: f(x)= 53.339789867786486
# differential_evolution step 225: f(x)= 53.3388871868471
# differential_evolution step 226: f(x)= 53.3388871868471
# differential_evolution step 227: f(x)= 53.3388871868471
# differential_evolution step 228: f(x)= 53.3388871868471
# differential_evolution step 229: f(x)= 53.3388871868471
# differential_evolution step 230: f(x)= 53.3388871868471
# differential_evolution step 231: f(x)= 53.3388871868471
# differential_evolution step 232: f(x)= 53.3228465372454
# differential_evolution step 233: f(x)= 53.3228465372454
# differential_evolution step 234: f(x)= 53.3228465372454
# differential_evolution step 235: f(x)= 53.3228465372454
# differential_evolution step 236: f(x)= 53.31817699921997
# differential_evolution step 237: f(x)= 53.315533294935186
# differential_evolution step 238: f(x)= 53.315533294935186
# differential_evolution step 239: f(x)= 53.315533294935186
# differential_evolution step 240: f(x)= 53.315533294935186
# differential_evolution step 241: f(x)= 53.315533294935186
# differential_evolution step 242: f(x)= 53.315533294935186
# differential_evolution step 243: f(x)= 53.315533294935186
# differential_evolution step 244: f(x)= 53.315533294935186
# differential_evolution step 245: f(x)= 53.31000126930102
# differential_evolution step 246: f(x)= 53.30197130116562
# differential_evolution step 247: f(x)= 53.30197130116562
# differential_evolution step 248: f(x)= 53.28822238130901
# differential_evolution step 249: f(x)= 53.28822238130901
# differential_evolution step 250: f(x)= 53.28822238130901
# differential_evolution step 251: f(x)= 53.28822238130901
# differential_evolution step 252: f(x)= 53.28822238130901
# differential_evolution step 253: f(x)= 53.28822238130901
# differential_evolution step 254: f(x)= 53.28822238130901
# differential_evolution step 255: f(x)= 53.28822238130901
# differential_evolution step 256: f(x)= 53.28822238130901
# differential_evolution step 257: f(x)= 53.28822238130901
# differential_evolution step 258: f(x)= 53.287202775029414
# differential_evolution step 259: f(x)= 53.287202775029414
# differential_evolution step 260: f(x)= 53.287202775029414
# differential_evolution step 261: f(x)= 53.287202775029414
# differential_evolution step 262: f(x)= 53.287202775029414
# differential_evolution step 263: f(x)= 53.287202775029414
# differential_evolution step 264: f(x)= 53.28398612672124
# differential_evolution step 265: f(x)= 53.28398612672124
# differential_evolution step 266: f(x)= 53.28398612672124
# differential_evolution step 267: f(x)= 53.28398612672124
# differential_evolution step 268: f(x)= 53.280409991368195
# differential_evolution step 269: f(x)= 53.280409991368195
# differential_evolution step 270: f(x)= 53.279535174770544
# differential_evolution step 271: f(x)= 53.279535174770544
# differential_evolution step 272: f(x)= 53.279535174770544
# differential_evolution step 273: f(x)= 53.279535174770544
# differential_evolution step 274: f(x)= 53.2773960856
# differential_evolution step 275: f(x)= 53.2773960856
# differential_evolution step 276: f(x)= 53.27497304894743
# differential_evolution step 277: f(x)= 53.27497304894743
# differential_evolution step 278: f(x)= 53.27497304894743
# differential_evolution step 279: f(x)= 53.27497304894743
# differential_evolution step 280: f(x)= 53.27497304894743
# differential_evolution step 281: f(x)= 53.27479951375437
# differential_evolution step 282: f(x)= 53.27479951375437
# differential_evolution step 283: f(x)= 53.27479951375437
# differential_evolution step 284: f(x)= 53.27479951375437
# differential_evolution step 285: f(x)= 53.27325636440767
# differential_evolution step 286: f(x)= 53.27325636440767
# differential_evolution step 287: f(x)= 53.27325636440767
# differential_evolution step 288: f(x)= 53.27325636440767
# differential_evolution step 289: f(x)= 53.27216700464762
# differential_evolution step 290: f(x)= 53.27216700464762
# differential_evolution step 291: f(x)= 53.27216700464762
# differential_evolution step 292: f(x)= 53.27216700464762
# differential_evolution step 293: f(x)= 53.27216700464762
# differential_evolution step 294: f(x)= 53.27216700464762
# differential_evolution step 295: f(x)= 53.27216700464762
# differential_evolution step 296: f(x)= 53.27216700464762
# differential_evolution step 297: f(x)= 53.27216700464762
# differential_evolution step 298: f(x)= 53.27216700464762
# differential_evolution step 299: f(x)= 53.27216700464762
# differential_evolution step 300: f(x)= 53.27216700464762
# differential_evolution step 301: f(x)= 53.27216700464762
# differential_evolution step 302: f(x)= 53.27216700464762
# differential_evolution step 303: f(x)= 53.27216700464762
# differential_evolution step 304: f(x)= 53.27216700464762
# differential_evolution step 305: f(x)= 53.27216700464762
# differential_evolution step 306: f(x)= 53.27216700464762
# differential_evolution step 307: f(x)= 53.27216700464762
# differential_evolution step 308: f(x)= 53.27216700464762
# differential_evolution step 309: f(x)= 53.27216700464762
# differential_evolution step 310: f(x)= 53.27216700464762
# differential_evolution step 311: f(x)= 53.27216700464762
# differential_evolution step 312: f(x)= 53.27216700464762
# differential_evolution step 313: f(x)= 53.27216700464762
# differential_evolution step 314: f(x)= 53.27216700464762
# differential_evolution step 315: f(x)= 53.271656635179866
# differential_evolution step 316: f(x)= 53.271656635179866
# differential_evolution step 317: f(x)= 53.271656635179866
# differential_evolution step 318: f(x)= 53.270181394871834
# differential_evolution step 319: f(x)= 53.270181394871834
# differential_evolution step 320: f(x)= 53.270181394871834
# differential_evolution step 321: f(x)= 53.270181394871834
# differential_evolution step 322: f(x)= 53.270181394871834
# differential_evolution step 323: f(x)= 53.270181394871834
# differential_evolution step 324: f(x)= 53.26991000225556
# differential_evolution step 325: f(x)= 53.26991000225556
# differential_evolution step 326: f(x)= 53.26991000225556
# differential_evolution step 327: f(x)= 53.26991000225556
# differential_evolution step 328: f(x)= 53.26991000225556
# differential_evolution step 329: f(x)= 53.26991000225556
# differential_evolution step 330: f(x)= 53.26991000225556
# differential_evolution step 331: f(x)= 53.26991000225556
# differential_evolution step 332: f(x)= 53.26991000225556
# differential_evolution step 333: f(x)= 53.26991000225556
# differential_evolution step 334: f(x)= 53.26991000225556
# differential_evolution step 335: f(x)= 53.26991000225556
# differential_evolution step 336: f(x)= 53.26988671175456
# differential_evolution step 337: f(x)= 53.26941420191687
# differential_evolution step 338: f(x)= 53.26941420191687
# differential_evolution step 339: f(x)= 53.26906191396598
# differential_evolution step 340: f(x)= 53.26906191396598
# differential_evolution step 341: f(x)= 53.26906191396598
# differential_evolution step 342: f(x)= 53.26906191396598
# differential_evolution step 343: f(x)= 53.26906191396598
# differential_evolution step 344: f(x)= 53.26906191396598
# differential_evolution step 345: f(x)= 53.26906191396598
# differential_evolution step 346: f(x)= 53.26906191396598
# differential_evolution step 347: f(x)= 53.26906191396598
# differential_evolution step 348: f(x)= 53.26906191396598
# differential_evolution step 349: f(x)= 53.26906191396598
# differential_evolution step 350: f(x)= 53.26906191396598
# differential_evolution step 351: f(x)= 53.26906191396598
# differential_evolution step 352: f(x)= 53.26906191396598
# differential_evolution step 353: f(x)= 53.26906191396598
# differential_evolution step 354: f(x)= 53.26906191396598
# differential_evolution step 355: f(x)= 53.26906191396598
# differential_evolution step 356: f(x)= 53.26867317252267
# differential_evolution step 357: f(x)= 53.26867317252267
# differential_evolution step 358: f(x)= 53.26867317252267
# differential_evolution step 359: f(x)= 53.26867317252267
# differential_evolution step 360: f(x)= 53.26867317252267
# differential_evolution step 361: f(x)= 53.26867317252267
# differential_evolution step 362: f(x)= 53.26867317252267
# differential_evolution step 363: f(x)= 53.26867317252267
# differential_evolution step 364: f(x)= 53.26867317252267
# differential_evolution step 365: f(x)= 53.26856669692751
# differential_evolution step 366: f(x)= 53.26856669692751
# differential_evolution step 367: f(x)= 53.26856669692751
# differential_evolution step 368: f(x)= 53.26856669692751
# differential_evolution step 369: f(x)= 53.26856669692751
# differential_evolution step 370: f(x)= 53.26856669692751
# differential_evolution step 371: f(x)= 53.26856669692751
# differential_evolution step 372: f(x)= 53.26856669692751
# differential_evolution step 373: f(x)= 53.2684102825332
# differential_evolution step 374: f(x)= 53.2684102825332
# differential_evolution step 375: f(x)= 53.2684102825332
# differential_evolution step 376: f(x)= 53.2684102825332
# differential_evolution step 377: f(x)= 53.2684102825332
# differential_evolution step 378: f(x)= 53.2684102825332
# differential_evolution step 379: f(x)= 53.2684102825332
# differential_evolution step 380: f(x)= 53.2684102825332
# differential_evolution step 381: f(x)= 53.2684102825332
# differential_evolution step 382: f(x)= 53.2684102825332
# differential_evolution step 383: f(x)= 53.2684102825332
# differential_evolution step 384: f(x)= 53.2684102825332
# differential_evolution step 385: f(x)= 53.2684102825332
# differential_evolution step 386: f(x)= 53.2684102825332
# differential_evolution step 387: f(x)= 53.2684102825332
# differential_evolution step 388: f(x)= 53.268324029230556
# differential_evolution step 389: f(x)= 53.268324029230556
# differential_evolution step 390: f(x)= 53.268278621399034
# differential_evolution step 391: f(x)= 53.268278621399034
# differential_evolution step 392: f(x)= 53.268278621399034
# differential_evolution step 393: f(x)= 53.268218449692924
# differential_evolution step 394: f(x)= 53.268218449692924
# differential_evolution step 395: f(x)= 53.268218449692924
# differential_evolution step 396: f(x)= 53.268218449692924
# differential_evolution step 397: f(x)= 53.268218449692924
# differential_evolution step 398: f(x)= 53.268218449692924
# differential_evolution step 399: f(x)= 53.268218449692924
# differential_evolution step 400: f(x)= 53.268218449692924
# differential_evolution step 401: f(x)= 53.268218449692924
# differential_evolution step 402: f(x)= 53.2682175086545
# differential_evolution step 403: f(x)= 53.2682175086545
# differential_evolution step 404: f(x)= 53.268215339156924
# differential_evolution step 405: f(x)= 53.268215339156924
# differential_evolution step 406: f(x)= 53.268215339156924
# differential_evolution step 407: f(x)= 53.268215339156924
# differential_evolution step 408: f(x)= 53.268215339156924
# differential_evolution step 409: f(x)= 53.268215339156924
# differential_evolution step 410: f(x)= 53.268215339156924
# differential_evolution step 411: f(x)= 53.26817566898756
# differential_evolution step 412: f(x)= 53.26817566898756
# differential_evolution step 413: f(x)= 53.268166613222185
# differential_evolution step 414: f(x)= 53.26812490547493
# differential_evolution step 415: f(x)= 53.26812490547493
# differential_evolution step 416: f(x)= 53.26812490547493
# differential_evolution step 417: f(x)= 53.26812490547493
# differential_evolution step 418: f(x)= 53.26812490547493
# differential_evolution step 419: f(x)= 53.26812490547493
# differential_evolution step 420: f(x)= 53.26812490547493
# differential_evolution step 421: f(x)= 53.26812490547493
# differential_evolution step 422: f(x)= 53.26812490547493
# differential_evolution step 423: f(x)= 53.26810164299268
# differential_evolution step 424: f(x)= 53.26810164299268
# differential_evolution step 425: f(x)= 53.26810164299268
# differential_evolution step 426: f(x)= 53.26810164299268
# differential_evolution step 427: f(x)= 53.26810164299268
# differential_evolution step 428: f(x)= 53.26810164299268
# differential_evolution step 429: f(x)= 53.26810164299268
# differential_evolution step 430: f(x)= 53.26810164299268
# differential_evolution step 431: f(x)= 53.26810164299268
# differential_evolution step 432: f(x)= 53.26810164299268
# differential_evolution step 433: f(x)= 53.26810164299268
# differential_evolution step 434: f(x)= 53.26810164299268
# differential_evolution step 435: f(x)= 53.268094225883246
# differential_evolution step 436: f(x)= 53.268094225883246
# differential_evolution step 437: f(x)= 53.26807798749673
# differential_evolution step 438: f(x)= 53.26807798749673
# differential_evolution step 439: f(x)= 53.26807798749673
# differential_evolution step 440: f(x)= 53.26807798749673
# differential_evolution step 441: f(x)= 53.26807798749673
# differential_evolution step 442: f(x)= 53.26807438786739
# differential_evolution step 443: f(x)= 53.26807438786739
# differential_evolution step 444: f(x)= 53.26807438786739
# differential_evolution step 445: f(x)= 53.268073773225304
# differential_evolution step 446: f(x)= 53.268073773225304
# differential_evolution step 447: f(x)= 53.268073773225304
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=10.9808, n=1.9702, x_0=39.6723
# Sérsic 2: I_e=1.0000, r_e=7.8465, n=0.9025, x_0=43.6216
# Sérsic 3: I_e=0.4997, r_e=9.4935, n=1.3684, x_0=57.2611
# Chi quadro minimo: 53.26804124876122
# True

# %%
plot_diff(x_axes, best_params, radial_profile_SII, r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_SII, covariance_SII = curve_fit(model_convolved, x_axes, radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII)

chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, radial_profile_error_SII,
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16936\3403565850.py:9: RuntimeWarning: overflow encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Sérsic 1: I_e=4.3144, r_e=3.8389, n=0.8830, x_0=39.7420
# Sérsic 2: I_e=2.7890, r_e=7.0502, n=0.0753, x_0=43.9352
# Sérsic 3: I_e=0.6566, r_e=8.7613, n=1.3245, x_0=57.0582
# [0.43957255 0.19290805 0.07727201 0.09046209 1.10102844 1.09993474
#  0.04324311 0.22675969 0.13824419 1.27617632 0.15179468 0.1202106 ]
# 38.00551742861427

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 365.155112190279
# differential_evolution step 2: f(x)= 253.71397944767276
# differential_evolution step 3: f(x)= 253.34144908069078
# differential_evolution step 4: f(x)= 149.08936236385335
# differential_evolution step 5: f(x)= 149.08936236385335
# differential_evolution step 6: f(x)= 135.1141815495146
# differential_evolution step 7: f(x)= 135.1141815495146
# differential_evolution step 8: f(x)= 115.71373347581977
# differential_evolution step 9: f(x)= 103.05393750806196
# differential_evolution step 10: f(x)= 103.05393750806196
# differential_evolution step 11: f(x)= 103.05393750806196
# differential_evolution step 12: f(x)= 100.23780572367497
# differential_evolution step 13: f(x)= 95.64457850058557
# differential_evolution step 14: f(x)= 95.64457850058557
# differential_evolution step 15: f(x)= 95.64457850058557
# differential_evolution step 16: f(x)= 95.64457850058557
# differential_evolution step 17: f(x)= 95.64457850058557
# differential_evolution step 18: f(x)= 95.64457850058557
# differential_evolution step 19: f(x)= 95.64457850058557
# differential_evolution step 20: f(x)= 82.14652001727168
# differential_evolution step 21: f(x)= 82.14652001727168
# differential_evolution step 22: f(x)= 82.14652001727168
# differential_evolution step 23: f(x)= 71.42010111972444
# differential_evolution step 24: f(x)= 71.42010111972444
# differential_evolution step 25: f(x)= 67.84347342165336
# differential_evolution step 26: f(x)= 67.84347342165336
# differential_evolution step 27: f(x)= 67.84347342165336
# differential_evolution step 28: f(x)= 67.84347342165336
# differential_evolution step 29: f(x)= 67.84347342165336
# differential_evolution step 30: f(x)= 63.212273575232736
# differential_evolution step 31: f(x)= 63.212273575232736
# differential_evolution step 32: f(x)= 59.31810648334888
# differential_evolution step 33: f(x)= 59.31810648334888
# differential_evolution step 34: f(x)= 59.31810648334888
# differential_evolution step 35: f(x)= 59.31810648334888
# differential_evolution step 36: f(x)= 59.31810648334888
# differential_evolution step 37: f(x)= 59.31810648334888
# differential_evolution step 38: f(x)= 57.89593786800372
# differential_evolution step 39: f(x)= 57.89593786800372
# differential_evolution step 40: f(x)= 54.18219614430785
# differential_evolution step 41: f(x)= 54.18219614430785
# differential_evolution step 42: f(x)= 54.18219614430785
# differential_evolution step 43: f(x)= 54.18219614430785
# differential_evolution step 44: f(x)= 54.18219614430785
# differential_evolution step 45: f(x)= 54.18219614430785
# differential_evolution step 46: f(x)= 54.18219614430785
# differential_evolution step 47: f(x)= 54.18219614430785
# differential_evolution step 48: f(x)= 54.18219614430785
# differential_evolution step 49: f(x)= 54.18219614430785
# differential_evolution step 50: f(x)= 54.18219614430785
# differential_evolution step 51: f(x)= 54.18219614430785
# differential_evolution step 52: f(x)= 54.18219614430785
# differential_evolution step 53: f(x)= 53.82659747956793
# differential_evolution step 54: f(x)= 51.80619397990584
# differential_evolution step 55: f(x)= 51.80619397990584
# differential_evolution step 56: f(x)= 51.80619397990584
# differential_evolution step 57: f(x)= 51.80619397990584
# differential_evolution step 58: f(x)= 51.80619397990584
# differential_evolution step 59: f(x)= 51.40451983732402
# differential_evolution step 60: f(x)= 50.423217017690085
# differential_evolution step 61: f(x)= 50.423217017690085
# differential_evolution step 62: f(x)= 50.423217017690085
# differential_evolution step 63: f(x)= 50.423217017690085
# differential_evolution step 64: f(x)= 50.327842130146514
# differential_evolution step 65: f(x)= 50.327842130146514
# differential_evolution step 66: f(x)= 50.327842130146514
# differential_evolution step 67: f(x)= 47.57604639053148
# differential_evolution step 68: f(x)= 45.214026328070126
# differential_evolution step 69: f(x)= 45.214026328070126
# differential_evolution step 70: f(x)= 45.214026328070126
# differential_evolution step 71: f(x)= 45.214026328070126
# differential_evolution step 72: f(x)= 45.214026328070126
# differential_evolution step 73: f(x)= 45.214026328070126
# differential_evolution step 74: f(x)= 45.214026328070126
# differential_evolution step 75: f(x)= 45.214026328070126
# differential_evolution step 76: f(x)= 45.214026328070126
# differential_evolution step 77: f(x)= 45.214026328070126
# differential_evolution step 78: f(x)= 42.09221390676253
# differential_evolution step 79: f(x)= 42.09221390676253
# differential_evolution step 80: f(x)= 42.09221390676253
# differential_evolution step 81: f(x)= 42.09221390676253
# differential_evolution step 82: f(x)= 42.09221390676253
# differential_evolution step 83: f(x)= 42.09221390676253
# differential_evolution step 84: f(x)= 42.09221390676253
# differential_evolution step 85: f(x)= 42.09221390676253
# differential_evolution step 86: f(x)= 42.09221390676253
# differential_evolution step 87: f(x)= 42.09221390676253
# differential_evolution step 88: f(x)= 42.09221390676253
# differential_evolution step 89: f(x)= 42.09221390676253
# differential_evolution step 90: f(x)= 42.09221390676253
# differential_evolution step 91: f(x)= 42.09221390676253
# differential_evolution step 92: f(x)= 42.09221390676253
# differential_evolution step 93: f(x)= 42.09221390676253
# differential_evolution step 94: f(x)= 42.09221390676253
# differential_evolution step 95: f(x)= 41.634440579329514
# differential_evolution step 96: f(x)= 41.634440579329514
# differential_evolution step 97: f(x)= 41.634440579329514
# differential_evolution step 98: f(x)= 41.634440579329514
# differential_evolution step 99: f(x)= 41.634440579329514
# differential_evolution step 100: f(x)= 41.634440579329514
# differential_evolution step 101: f(x)= 41.634440579329514
# differential_evolution step 102: f(x)= 41.634440579329514
# differential_evolution step 103: f(x)= 41.634440579329514
# differential_evolution step 104: f(x)= 41.634440579329514
# differential_evolution step 105: f(x)= 40.8247432129713
# differential_evolution step 106: f(x)= 40.8247432129713
# differential_evolution step 107: f(x)= 40.8247432129713
# differential_evolution step 108: f(x)= 40.8247432129713
# differential_evolution step 109: f(x)= 40.8247432129713
# differential_evolution step 110: f(x)= 40.8247432129713
# differential_evolution step 111: f(x)= 40.8247432129713
# differential_evolution step 112: f(x)= 40.8247432129713
# differential_evolution step 113: f(x)= 40.717119937287535
# differential_evolution step 114: f(x)= 40.717119937287535
# differential_evolution step 115: f(x)= 40.717119937287535
# differential_evolution step 116: f(x)= 40.717119937287535
# differential_evolution step 117: f(x)= 40.717119937287535
# differential_evolution step 118: f(x)= 40.717119937287535
# differential_evolution step 119: f(x)= 40.717119937287535
# differential_evolution step 120: f(x)= 40.717119937287535
# differential_evolution step 121: f(x)= 40.717119937287535
# differential_evolution step 122: f(x)= 40.58598631038976
# differential_evolution step 123: f(x)= 40.260743373305075
# differential_evolution step 124: f(x)= 40.260743373305075
# differential_evolution step 125: f(x)= 39.99427934140298
# differential_evolution step 126: f(x)= 39.99427934140298
# differential_evolution step 127: f(x)= 39.99427934140298
# differential_evolution step 128: f(x)= 39.99427934140298
# differential_evolution step 129: f(x)= 39.99427934140298
# differential_evolution step 130: f(x)= 39.937831211525236
# differential_evolution step 131: f(x)= 39.64875596304478
# differential_evolution step 132: f(x)= 39.64875596304478
# differential_evolution step 133: f(x)= 39.64875596304478
# differential_evolution step 134: f(x)= 39.64875596304478
# differential_evolution step 135: f(x)= 39.64875596304478
# differential_evolution step 136: f(x)= 39.64875596304478
# differential_evolution step 137: f(x)= 39.64875596304478
# differential_evolution step 138: f(x)= 39.64535997604257
# differential_evolution step 139: f(x)= 39.402041258795975
# differential_evolution step 140: f(x)= 39.402041258795975
# differential_evolution step 141: f(x)= 39.402041258795975
# differential_evolution step 142: f(x)= 39.402041258795975
# differential_evolution step 143: f(x)= 39.402041258795975
# differential_evolution step 144: f(x)= 39.28952380146454
# differential_evolution step 145: f(x)= 39.28952380146454
# differential_evolution step 146: f(x)= 39.18789180975224
# differential_evolution step 147: f(x)= 39.18789180975224
# differential_evolution step 148: f(x)= 39.18789180975224
# differential_evolution step 149: f(x)= 39.18789180975224
# differential_evolution step 150: f(x)= 39.18789180975224
# differential_evolution step 151: f(x)= 39.18789180975224
# differential_evolution step 152: f(x)= 39.18789180975224
# differential_evolution step 153: f(x)= 39.18789180975224
# differential_evolution step 154: f(x)= 39.146002320435535
# differential_evolution step 155: f(x)= 39.129408703091514
# differential_evolution step 156: f(x)= 39.129408703091514
# differential_evolution step 157: f(x)= 39.129408703091514
# differential_evolution step 158: f(x)= 39.129408703091514
# differential_evolution step 159: f(x)= 39.129408703091514
# differential_evolution step 160: f(x)= 39.129408703091514
# differential_evolution step 161: f(x)= 39.129408703091514
# differential_evolution step 162: f(x)= 39.129408703091514
# differential_evolution step 163: f(x)= 39.129408703091514
# differential_evolution step 164: f(x)= 39.129408703091514
# differential_evolution step 165: f(x)= 39.129408703091514
# differential_evolution step 166: f(x)= 39.129408703091514
# differential_evolution step 167: f(x)= 39.06536971858992
# differential_evolution step 168: f(x)= 39.06202805634353
# differential_evolution step 169: f(x)= 39.06202805634353
# differential_evolution step 170: f(x)= 39.02962993402274
# differential_evolution step 171: f(x)= 39.02962993402274
# differential_evolution step 172: f(x)= 39.02962993402274
# differential_evolution step 173: f(x)= 39.02962993402274
# differential_evolution step 174: f(x)= 39.02962993402274
# differential_evolution step 175: f(x)= 39.02962993402274
# differential_evolution step 176: f(x)= 39.02962993402274
# differential_evolution step 177: f(x)= 39.02962993402274
# differential_evolution step 178: f(x)= 39.02962993402274
# differential_evolution step 179: f(x)= 39.02962993402274
# differential_evolution step 180: f(x)= 39.02962993402274
# differential_evolution step 181: f(x)= 39.02962993402274
# differential_evolution step 182: f(x)= 38.975833210513464
# differential_evolution step 183: f(x)= 38.975833210513464
# differential_evolution step 184: f(x)= 38.975833210513464
# differential_evolution step 185: f(x)= 38.975833210513464
# differential_evolution step 186: f(x)= 38.975833210513464
# differential_evolution step 187: f(x)= 38.975833210513464
# differential_evolution step 188: f(x)= 38.975833210513464
# differential_evolution step 189: f(x)= 38.975833210513464
# differential_evolution step 190: f(x)= 38.89644404135456
# differential_evolution step 191: f(x)= 38.89644404135456
# differential_evolution step 192: f(x)= 38.89644404135456
# differential_evolution step 193: f(x)= 38.89644404135456
# differential_evolution step 194: f(x)= 38.88048851667992
# differential_evolution step 195: f(x)= 38.88048851667992
# differential_evolution step 196: f(x)= 38.88048851667992
# differential_evolution step 197: f(x)= 38.88048851667992
# differential_evolution step 198: f(x)= 38.88048851667992
# differential_evolution step 199: f(x)= 38.88048851667992
# differential_evolution step 200: f(x)= 38.86622648056408
# differential_evolution step 201: f(x)= 38.86622648056408
# differential_evolution step 202: f(x)= 38.86622648056408
# differential_evolution step 203: f(x)= 38.86622648056408
# differential_evolution step 204: f(x)= 38.86622648056408
# differential_evolution step 205: f(x)= 38.86132967858278
# differential_evolution step 206: f(x)= 38.86132967858278
# differential_evolution step 207: f(x)= 38.86132967858278
# differential_evolution step 208: f(x)= 38.86132967858278
# differential_evolution step 209: f(x)= 38.83700040218203
# differential_evolution step 210: f(x)= 38.83565266622003
# differential_evolution step 211: f(x)= 38.82354627429574
# differential_evolution step 212: f(x)= 38.82354627429574
# differential_evolution step 213: f(x)= 38.82354627429574
# differential_evolution step 214: f(x)= 38.82354627429574
# differential_evolution step 215: f(x)= 38.82354627429574
# differential_evolution step 216: f(x)= 38.82354627429574
# differential_evolution step 217: f(x)= 38.78096825181199
# differential_evolution step 218: f(x)= 38.78096825181199
# differential_evolution step 219: f(x)= 38.78096825181199
# differential_evolution step 220: f(x)= 38.78096825181199
# differential_evolution step 221: f(x)= 38.78096825181199
# differential_evolution step 222: f(x)= 38.78096825181199
# differential_evolution step 223: f(x)= 38.77909752712859
# differential_evolution step 224: f(x)= 38.772301165249374
# differential_evolution step 225: f(x)= 38.772301165249374
# differential_evolution step 226: f(x)= 38.771612628160746
# differential_evolution step 227: f(x)= 38.771612628160746
# differential_evolution step 228: f(x)= 38.771612628160746
# differential_evolution step 229: f(x)= 38.771612628160746
# differential_evolution step 230: f(x)= 38.771612628160746
# differential_evolution step 231: f(x)= 38.771612628160746
# differential_evolution step 232: f(x)= 38.76434148547544
# differential_evolution step 233: f(x)= 38.751594898400334
# differential_evolution step 234: f(x)= 38.751594898400334
# differential_evolution step 235: f(x)= 38.751594898400334
# differential_evolution step 236: f(x)= 38.751594898400334
# differential_evolution step 237: f(x)= 38.751594898400334
# differential_evolution step 238: f(x)= 38.751594898400334
# differential_evolution step 239: f(x)= 38.751594898400334
# differential_evolution step 240: f(x)= 38.751594898400334
# differential_evolution step 241: f(x)= 38.751594898400334
# differential_evolution step 242: f(x)= 38.747443304175135
# differential_evolution step 243: f(x)= 38.747443304175135
# differential_evolution step 244: f(x)= 38.747443304175135
# differential_evolution step 245: f(x)= 38.747443304175135
# differential_evolution step 246: f(x)= 38.73997855793819
# differential_evolution step 247: f(x)= 38.73997855793819
# differential_evolution step 248: f(x)= 38.73997855793819
# differential_evolution step 249: f(x)= 38.729849715111314
# differential_evolution step 250: f(x)= 38.729849715111314
# differential_evolution step 251: f(x)= 38.729849715111314
# differential_evolution step 252: f(x)= 38.729849715111314
# differential_evolution step 253: f(x)= 38.729849715111314
# differential_evolution step 254: f(x)= 38.729849715111314
# differential_evolution step 255: f(x)= 38.729849715111314
# differential_evolution step 256: f(x)= 38.729849715111314
# differential_evolution step 257: f(x)= 38.729849715111314
# differential_evolution step 258: f(x)= 38.729849715111314
# differential_evolution step 259: f(x)= 38.729849715111314
# differential_evolution step 260: f(x)= 38.729849715111314
# differential_evolution step 261: f(x)= 38.729849715111314
# differential_evolution step 262: f(x)= 38.729849715111314
# differential_evolution step 263: f(x)= 38.729849715111314
# differential_evolution step 264: f(x)= 38.729849715111314
# differential_evolution step 265: f(x)= 38.729818928093714
# differential_evolution step 266: f(x)= 38.729818928093714
# differential_evolution step 267: f(x)= 38.729818928093714
# differential_evolution step 268: f(x)= 38.724684543023315
# differential_evolution step 269: f(x)= 38.724684543023315
# differential_evolution step 270: f(x)= 38.724684543023315
# differential_evolution step 271: f(x)= 38.724684543023315
# differential_evolution step 272: f(x)= 38.724684543023315
# differential_evolution step 273: f(x)= 38.724684543023315
# differential_evolution step 274: f(x)= 38.724684543023315
# differential_evolution step 275: f(x)= 38.724684543023315
# differential_evolution step 276: f(x)= 38.724684543023315
# differential_evolution step 277: f(x)= 38.724684543023315
# differential_evolution step 278: f(x)= 38.724684543023315
# differential_evolution step 279: f(x)= 38.724684543023315
# differential_evolution step 280: f(x)= 38.724684543023315
# differential_evolution step 281: f(x)= 38.71974726713716
# differential_evolution step 282: f(x)= 38.71974726713716
# differential_evolution step 283: f(x)= 38.71974726713716
# differential_evolution step 284: f(x)= 38.71974726713716
# differential_evolution step 285: f(x)= 38.71974726713716
# differential_evolution step 286: f(x)= 38.71974726713716
# differential_evolution step 287: f(x)= 38.71974726713716
# differential_evolution step 288: f(x)= 38.71974726713716
# differential_evolution step 289: f(x)= 38.71974726713716
# differential_evolution step 290: f(x)= 38.71974726713716
# differential_evolution step 291: f(x)= 38.71974726713716
# differential_evolution step 292: f(x)= 38.71974726713716
# differential_evolution step 293: f(x)= 38.71974726713716
# differential_evolution step 294: f(x)= 38.71974726713716
# differential_evolution step 295: f(x)= 38.71974726713716
# differential_evolution step 296: f(x)= 38.71974726713716
# differential_evolution step 297: f(x)= 38.71974726713716
# differential_evolution step 298: f(x)= 38.71974726713716
# differential_evolution step 299: f(x)= 38.71974726713716
# differential_evolution step 300: f(x)= 38.71974726713716
# differential_evolution step 301: f(x)= 38.71974726713716
# differential_evolution step 302: f(x)= 38.71974726713716
# differential_evolution step 303: f(x)= 38.71916095415839
# differential_evolution step 304: f(x)= 38.71916095415839
# differential_evolution step 305: f(x)= 38.71916095415839
# differential_evolution step 306: f(x)= 38.71916095415839
# differential_evolution step 307: f(x)= 38.71916095415839
# differential_evolution step 308: f(x)= 38.71916095415839
# differential_evolution step 309: f(x)= 38.71916095415839
# differential_evolution step 310: f(x)= 38.71916095415839
# differential_evolution step 311: f(x)= 38.71916095415839
# differential_evolution step 312: f(x)= 38.71916095415839
# differential_evolution step 313: f(x)= 38.71916095415839
# differential_evolution step 314: f(x)= 38.71916095415839
# differential_evolution step 315: f(x)= 38.717870116620624
# differential_evolution step 316: f(x)= 38.717870116620624
# differential_evolution step 317: f(x)= 38.717870116620624
# differential_evolution step 318: f(x)= 38.717199260973395
# differential_evolution step 319: f(x)= 38.717199260973395
# differential_evolution step 320: f(x)= 38.717199260973395
# differential_evolution step 321: f(x)= 38.717199260973395
# differential_evolution step 322: f(x)= 38.71619203074878
# differential_evolution step 323: f(x)= 38.71617471045682
# differential_evolution step 324: f(x)= 38.714922078653984
# differential_evolution step 325: f(x)= 38.714922078653984
# differential_evolution step 326: f(x)= 38.714922078653984
# differential_evolution step 327: f(x)= 38.714922078653984
# differential_evolution step 328: f(x)= 38.714922078653984
# differential_evolution step 329: f(x)= 38.714922078653984
# differential_evolution step 330: f(x)= 38.714922078653984
# differential_evolution step 331: f(x)= 38.714922078653984
# differential_evolution step 332: f(x)= 38.714922078653984
# differential_evolution step 333: f(x)= 38.714922078653984
# differential_evolution step 334: f(x)= 38.714922078653984
# differential_evolution step 335: f(x)= 38.714922078653984
# differential_evolution step 336: f(x)= 38.714922078653984
# differential_evolution step 337: f(x)= 38.714922078653984
# differential_evolution step 338: f(x)= 38.714922078653984
# differential_evolution step 339: f(x)= 38.714922078653984
# differential_evolution step 340: f(x)= 38.714922078653984
# differential_evolution step 341: f(x)= 38.714922078653984
# differential_evolution step 342: f(x)= 38.714922078653984
# differential_evolution step 343: f(x)= 38.714922078653984
# differential_evolution step 344: f(x)= 38.714470632997575
# differential_evolution step 345: f(x)= 38.714470632997575
# differential_evolution step 346: f(x)= 38.714470632997575
# differential_evolution step 347: f(x)= 38.714470632997575
# differential_evolution step 348: f(x)= 38.714470632997575
# differential_evolution step 349: f(x)= 38.714470632997575
# differential_evolution step 350: f(x)= 38.714470632997575
# differential_evolution step 351: f(x)= 38.714470632997575
# differential_evolution step 352: f(x)= 38.714470632997575
# differential_evolution step 353: f(x)= 38.714470632997575
# differential_evolution step 354: f(x)= 38.714470632997575
# differential_evolution step 355: f(x)= 38.714470632997575
# differential_evolution step 356: f(x)= 38.714470632997575
# differential_evolution step 357: f(x)= 38.71429990414406
# differential_evolution step 358: f(x)= 38.71429990414406
# differential_evolution step 359: f(x)= 38.71429990414406
# differential_evolution step 360: f(x)= 38.71429990414406
# differential_evolution step 361: f(x)= 38.71429990414406
# differential_evolution step 362: f(x)= 38.71429990414406
# differential_evolution step 363: f(x)= 38.71429990414406
# differential_evolution step 364: f(x)= 38.71429990414406
# differential_evolution step 365: f(x)= 38.71429990414406
# differential_evolution step 366: f(x)= 38.71429990414406
# differential_evolution step 367: f(x)= 38.71429990414406
# differential_evolution step 368: f(x)= 38.71429990414406
# differential_evolution step 369: f(x)= 38.71414495992514
# differential_evolution step 370: f(x)= 38.71414495992514
# differential_evolution step 371: f(x)= 38.71414495992514
# differential_evolution step 372: f(x)= 38.71414495992514
# differential_evolution step 373: f(x)= 38.71414495992514
# differential_evolution step 374: f(x)= 38.71408839512445
# differential_evolution step 375: f(x)= 38.71408839512445
# differential_evolution step 376: f(x)= 38.71374489508315
# differential_evolution step 377: f(x)= 38.71374489508315
# differential_evolution step 378: f(x)= 38.71374489508315
# differential_evolution step 379: f(x)= 38.71374489508315
# differential_evolution step 380: f(x)= 38.71374489508315
# differential_evolution step 381: f(x)= 38.71374489508315
# differential_evolution step 382: f(x)= 38.713661887711815
# differential_evolution step 383: f(x)= 38.713661887711815
# differential_evolution step 384: f(x)= 38.713661887711815
# differential_evolution step 385: f(x)= 38.713661887711815
# differential_evolution step 386: f(x)= 38.713661887711815
# differential_evolution step 387: f(x)= 38.713661887711815
# differential_evolution step 388: f(x)= 38.713661887711815
# differential_evolution step 389: f(x)= 38.713661887711815
# differential_evolution step 390: f(x)= 38.713661887711815
# differential_evolution step 391: f(x)= 38.713393562624596
# differential_evolution step 392: f(x)= 38.713393562624596
# differential_evolution step 393: f(x)= 38.713393562624596
# differential_evolution step 394: f(x)= 38.713393562624596
# differential_evolution step 395: f(x)= 38.713393562624596
# differential_evolution step 396: f(x)= 38.713393562624596
# differential_evolution step 397: f(x)= 38.713393562624596
# differential_evolution step 398: f(x)= 38.713393562624596
# differential_evolution step 399: f(x)= 38.713393562624596
# differential_evolution step 400: f(x)= 38.71325713714175
# differential_evolution step 401: f(x)= 38.71325713714175
# differential_evolution step 402: f(x)= 38.71325713714175
# differential_evolution step 403: f(x)= 38.71325713714175
# differential_evolution step 404: f(x)= 38.71325713714175
# differential_evolution step 405: f(x)= 38.71325713714175
# differential_evolution step 406: f(x)= 38.71325713714175
# differential_evolution step 407: f(x)= 38.71325713714175
# differential_evolution step 408: f(x)= 38.71325713714175
# differential_evolution step 409: f(x)= 38.71319976258646
# differential_evolution step 410: f(x)= 38.713187906015854
# differential_evolution step 411: f(x)= 38.713187906015854
# differential_evolution step 412: f(x)= 38.713187906015854
# differential_evolution step 413: f(x)= 38.713187906015854
# differential_evolution step 414: f(x)= 38.713187906015854
# differential_evolution step 415: f(x)= 38.713187906015854
# differential_evolution step 416: f(x)= 38.713187906015854
# differential_evolution step 417: f(x)= 38.713187906015854
# differential_evolution step 418: f(x)= 38.713187906015854
# differential_evolution step 419: f(x)= 38.713187906015854
# differential_evolution step 420: f(x)= 38.713187906015854
# differential_evolution step 421: f(x)= 38.713187906015854
# differential_evolution step 422: f(x)= 38.713187906015854
# differential_evolution step 423: f(x)= 38.713187906015854
# differential_evolution step 424: f(x)= 38.713187906015854
# differential_evolution step 425: f(x)= 38.713187906015854
# differential_evolution step 426: f(x)= 38.713187906015854
# differential_evolution step 427: f(x)= 38.713187906015854
# differential_evolution step 428: f(x)= 38.713187906015854
# differential_evolution step 429: f(x)= 38.713187906015854
# differential_evolution step 430: f(x)= 38.713187906015854
# differential_evolution step 431: f(x)= 38.713187906015854
# differential_evolution step 432: f(x)= 38.713187906015854
# differential_evolution step 433: f(x)= 38.713187906015854
# differential_evolution step 434: f(x)= 38.713187906015854
# differential_evolution step 435: f(x)= 38.71311833382676
# differential_evolution step 436: f(x)= 38.71311833382676
# differential_evolution step 437: f(x)= 38.71311833382676
# differential_evolution step 438: f(x)= 38.71311833382676
# differential_evolution step 439: f(x)= 38.71311833382676
# differential_evolution step 440: f(x)= 38.71311374905162
# differential_evolution step 441: f(x)= 38.71311374905162
# differential_evolution step 442: f(x)= 38.71311374905162
# differential_evolution step 443: f(x)= 38.71311374905162
# differential_evolution step 444: f(x)= 38.71311374905162
# differential_evolution step 445: f(x)= 38.71311374905162
# differential_evolution step 446: f(x)= 38.71311374905162
# differential_evolution step 447: f(x)= 38.71311374905162
# differential_evolution step 448: f(x)= 38.71311374905162
# differential_evolution step 449: f(x)= 38.71311374905162
# differential_evolution step 450: f(x)= 38.71311374905162
# differential_evolution step 451: f(x)= 38.71311374905162
# differential_evolution step 452: f(x)= 38.71311374905162
# differential_evolution step 453: f(x)= 38.71311374905162
# differential_evolution step 454: f(x)= 38.71311374905162
# differential_evolution step 455: f(x)= 38.71311374905162
# differential_evolution step 456: f(x)= 38.71311374905162
# differential_evolution step 457: f(x)= 38.71311374905162
# differential_evolution step 458: f(x)= 38.713089947150344
# differential_evolution step 459: f(x)= 38.713089947150344
# differential_evolution step 460: f(x)= 38.713089947150344
# differential_evolution step 461: f(x)= 38.713089947150344
# differential_evolution step 462: f(x)= 38.713089947150344
# differential_evolution step 463: f(x)= 38.713089947150344
# differential_evolution step 464: f(x)= 38.713089947150344
# differential_evolution step 465: f(x)= 38.713089947150344
# differential_evolution step 466: f(x)= 38.713081358045834
# differential_evolution step 467: f(x)= 38.713081358045834
# differential_evolution step 468: f(x)= 38.713081358045834
# differential_evolution step 469: f(x)= 38.713081358045834
# differential_evolution step 470: f(x)= 38.713081358045834
# differential_evolution step 471: f(x)= 38.713081358045834
# differential_evolution step 472: f(x)= 38.713081358045834
# differential_evolution step 473: f(x)= 38.713081358045834
# differential_evolution step 474: f(x)= 38.713081358045834
# differential_evolution step 475: f(x)= 38.713081358045834
# differential_evolution step 476: f(x)= 38.713081358045834
# differential_evolution step 477: f(x)= 38.713081358045834
# differential_evolution step 478: f(x)= 38.713081358045834
# differential_evolution step 479: f(x)= 38.713081358045834
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=9.9818, n=2.0431, x_0=39.9171
# Sérsic 2: I_e=1.0000, r_e=7.3025, n=0.9102, x_0=43.6216
# Sérsic 3: I_e=0.7414, r_e=10.0399, n=1.2476, x_0=57.9312
# Chi quadro minimo: 38.71304728831459
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII, r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(model_convolved, x_axes, radial_profile_OIII, p0=result.x, sigma = radial_profile_error_OIII, bounds = bounds_list, maxfev=10000)


chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, radial_profile_error_OIII,
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Sérsic 1: I_e=1.0000, r_e=8.3642, n=2.1373, x_0=39.8946
# Sérsic 2: I_e=1.0000, r_e=7.9345, n=0.9779, x_0=43.6216
# Sérsic 3: I_e=0.7344, r_e=9.9582, n=1.2442, x_0=57.9312
# [1.28556712 8.38703483 0.89901663 0.11926872 1.16687222 8.34473353
#  0.70534514 1.37745489 0.37069868 3.06987024 0.32191771 0.31448596]
# 91.86343793477704

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 44763.41031408579
# differential_evolution step 2: f(x)= 44763.41031408579
# differential_evolution step 3: f(x)= 32295.560155717783
# differential_evolution step 4: f(x)= 32295.560155717783
# differential_evolution step 5: f(x)= 28986.764643131897
# differential_evolution step 6: f(x)= 28986.764643131897
# differential_evolution step 7: f(x)= 28986.764643131897
# differential_evolution step 8: f(x)= 25735.939051404235
# differential_evolution step 9: f(x)= 25735.939051404235
# differential_evolution step 10: f(x)= 25735.939051404235
# differential_evolution step 11: f(x)= 25735.939051404235
# differential_evolution step 12: f(x)= 21434.258888966782
# differential_evolution step 13: f(x)= 21434.258888966782
# differential_evolution step 14: f(x)= 21434.258888966782
# differential_evolution step 15: f(x)= 21434.258888966782
# differential_evolution step 16: f(x)= 21434.258888966782
# differential_evolution step 17: f(x)= 17740.149075477057
# differential_evolution step 18: f(x)= 17740.149075477057
# differential_evolution step 19: f(x)= 17740.149075477057
# differential_evolution step 20: f(x)= 17168.99563743505
# differential_evolution step 21: f(x)= 17168.99563743505
# differential_evolution step 22: f(x)= 17168.99563743505
# differential_evolution step 23: f(x)= 17168.99563743505
# differential_evolution step 24: f(x)= 17168.99563743505
# differential_evolution step 25: f(x)= 17168.99563743505
# differential_evolution step 26: f(x)= 17168.99563743505
# differential_evolution step 27: f(x)= 16732.372354120933
# differential_evolution step 28: f(x)= 16732.372354120933
# differential_evolution step 29: f(x)= 16732.372354120933
# differential_evolution step 30: f(x)= 16732.372354120933
# differential_evolution step 31: f(x)= 16732.372354120933
# differential_evolution step 32: f(x)= 16323.991041279154
# differential_evolution step 33: f(x)= 15152.952006919924
# differential_evolution step 34: f(x)= 15152.952006919924
# differential_evolution step 35: f(x)= 15152.952006919924
# differential_evolution step 36: f(x)= 15152.952006919924
# differential_evolution step 37: f(x)= 14755.667529525552
# differential_evolution step 38: f(x)= 14755.667529525552
# differential_evolution step 39: f(x)= 14755.667529525552
# differential_evolution step 40: f(x)= 14303.907533939111
# differential_evolution step 41: f(x)= 14303.907533939111
# differential_evolution step 42: f(x)= 14303.907533939111
# differential_evolution step 43: f(x)= 13982.933082344132
# differential_evolution step 44: f(x)= 13982.933082344132
# differential_evolution step 45: f(x)= 13982.933082344132
# differential_evolution step 46: f(x)= 13982.933082344132
# differential_evolution step 47: f(x)= 13982.933082344132
# differential_evolution step 48: f(x)= 13982.933082344132
# differential_evolution step 49: f(x)= 13982.933082344132
# differential_evolution step 50: f(x)= 13982.933082344132
# differential_evolution step 51: f(x)= 13982.933082344132
# differential_evolution step 52: f(x)= 13956.835254591246
# differential_evolution step 53: f(x)= 13956.835254591246
# differential_evolution step 54: f(x)= 13956.835254591246
# differential_evolution step 55: f(x)= 13956.835254591246
# differential_evolution step 56: f(x)= 13910.67373775714
# differential_evolution step 57: f(x)= 13526.274092690268
# differential_evolution step 58: f(x)= 13371.652913448766
# differential_evolution step 59: f(x)= 13371.652913448766
# differential_evolution step 60: f(x)= 13371.652913448766
# differential_evolution step 61: f(x)= 13371.652913448766
# differential_evolution step 62: f(x)= 13371.652913448766
# differential_evolution step 63: f(x)= 13371.652913448766
# differential_evolution step 64: f(x)= 13371.652913448766
# differential_evolution step 65: f(x)= 13371.652913448766
# differential_evolution step 66: f(x)= 13371.652913448766
# differential_evolution step 67: f(x)= 13371.652913448766
# differential_evolution step 68: f(x)= 13371.652913448766
# differential_evolution step 69: f(x)= 13371.652913448766
# differential_evolution step 70: f(x)= 13371.652913448766
# differential_evolution step 71: f(x)= 13371.652913448766
# differential_evolution step 72: f(x)= 13371.652913448766
# differential_evolution step 73: f(x)= 13371.652913448766
# differential_evolution step 74: f(x)= 13371.652913448766
# differential_evolution step 75: f(x)= 13363.614485296472
# differential_evolution step 76: f(x)= 13363.614485296472
# differential_evolution step 77: f(x)= 13363.614485296472
# differential_evolution step 78: f(x)= 13363.614485296472
# differential_evolution step 79: f(x)= 13362.335122385643
# differential_evolution step 80: f(x)= 13292.06691612803
# differential_evolution step 81: f(x)= 13292.06691612803
# differential_evolution step 82: f(x)= 13166.605467559426
# differential_evolution step 83: f(x)= 13166.605467559426
# differential_evolution step 84: f(x)= 13166.605467559426
# differential_evolution step 85: f(x)= 13166.605467559426
# differential_evolution step 86: f(x)= 13166.605467559426
# differential_evolution step 87: f(x)= 13166.605467559426
# differential_evolution step 88: f(x)= 13166.605467559426
# differential_evolution step 89: f(x)= 13166.605467559426
# differential_evolution step 90: f(x)= 13166.605467559426
# differential_evolution step 91: f(x)= 13166.605467559426
# differential_evolution step 92: f(x)= 13166.605467559426
# differential_evolution step 93: f(x)= 13166.605467559426
# differential_evolution step 94: f(x)= 13166.605467559426
# differential_evolution step 95: f(x)= 13166.605467559426
# differential_evolution step 96: f(x)= 13166.605467559426
# differential_evolution step 97: f(x)= 13120.899635397505
# differential_evolution step 98: f(x)= 13120.899635397505
# differential_evolution step 99: f(x)= 13120.899635397505
# differential_evolution step 100: f(x)= 13120.899635397505
# differential_evolution step 101: f(x)= 13120.899635397505
# differential_evolution step 102: f(x)= 13120.899635397505
# differential_evolution step 103: f(x)= 13120.899635397505
# differential_evolution step 104: f(x)= 13120.899635397505
# differential_evolution step 105: f(x)= 13120.899635397505
# differential_evolution step 106: f(x)= 13120.899635397505
# differential_evolution step 107: f(x)= 13120.899635397505
# differential_evolution step 108: f(x)= 13120.899635397505
# differential_evolution step 109: f(x)= 13120.899635397505
# differential_evolution step 110: f(x)= 13120.899635397505
# differential_evolution step 111: f(x)= 13120.899635397505
# differential_evolution step 112: f(x)= 13120.899635397505
# differential_evolution step 113: f(x)= 13120.899635397505
# differential_evolution step 114: f(x)= 13120.899635397505
# differential_evolution step 115: f(x)= 13120.899635397505
# differential_evolution step 116: f(x)= 13120.899635397505
# differential_evolution step 117: f(x)= 13120.899635397505
# differential_evolution step 118: f(x)= 13120.899635397505
# differential_evolution step 119: f(x)= 13120.899635397505
# differential_evolution step 120: f(x)= 13116.759581666545
# differential_evolution step 121: f(x)= 13101.326755677586
# differential_evolution step 122: f(x)= 13101.326755677586
# differential_evolution step 123: f(x)= 13101.326755677586
# differential_evolution step 124: f(x)= 13089.385972821347
# differential_evolution step 125: f(x)= 13089.385972821347
# differential_evolution step 126: f(x)= 13080.597435480708
# differential_evolution step 127: f(x)= 13080.597435480708
# differential_evolution step 128: f(x)= 13080.597435480708
# differential_evolution step 129: f(x)= 13080.597435480708
# differential_evolution step 130: f(x)= 13080.597435480708
# differential_evolution step 131: f(x)= 13080.597435480708
# differential_evolution step 132: f(x)= 13080.597435480708
# differential_evolution step 133: f(x)= 13080.597435480708
# differential_evolution step 134: f(x)= 13080.597435480708
# differential_evolution step 135: f(x)= 13080.597435480708
# differential_evolution step 136: f(x)= 13080.597435480708
# differential_evolution step 137: f(x)= 13080.597435480708
# differential_evolution step 138: f(x)= 13080.597435480708
# differential_evolution step 139: f(x)= 13080.597435480708
# differential_evolution step 140: f(x)= 13080.597435480708
# differential_evolution step 141: f(x)= 13080.597435480708
# differential_evolution step 142: f(x)= 13080.597435480708
# differential_evolution step 143: f(x)= 13077.864584334457
# differential_evolution step 144: f(x)= 13077.864584334457
# differential_evolution step 145: f(x)= 13074.923258547522
# differential_evolution step 146: f(x)= 13074.923258547522
# differential_evolution step 147: f(x)= 13074.923258547522
# differential_evolution step 148: f(x)= 13074.923258547522
# differential_evolution step 149: f(x)= 13074.923258547522
# differential_evolution step 150: f(x)= 13074.923258547522
# differential_evolution step 151: f(x)= 13074.923258547522
# differential_evolution step 152: f(x)= 13074.923258547522
# differential_evolution step 153: f(x)= 13074.923258547522
# differential_evolution step 154: f(x)= 13074.923258547522
# differential_evolution step 155: f(x)= 13074.923258547522
# differential_evolution step 156: f(x)= 13074.923258547522
# differential_evolution step 157: f(x)= 13074.923258547522
# differential_evolution step 158: f(x)= 13074.923258547522
# differential_evolution step 159: f(x)= 13074.923258547522
# differential_evolution step 160: f(x)= 13074.923258547522
# differential_evolution step 161: f(x)= 13074.923258547522
# differential_evolution step 162: f(x)= 13074.923258547522
# differential_evolution step 163: f(x)= 13074.923258547522
# differential_evolution step 164: f(x)= 13074.923258547522
# differential_evolution step 165: f(x)= 13071.306351947376
# differential_evolution step 166: f(x)= 13071.306351947376
# differential_evolution step 167: f(x)= 13071.306351947376
# differential_evolution step 168: f(x)= 13071.306351947376
# differential_evolution step 169: f(x)= 13071.306351947376
# differential_evolution step 170: f(x)= 13071.306351947376
# differential_evolution step 171: f(x)= 13070.702702260583
# differential_evolution step 172: f(x)= 13065.251799616939
# differential_evolution step 173: f(x)= 13065.251799616939
# differential_evolution step 174: f(x)= 13065.251799616939
# differential_evolution step 175: f(x)= 13065.251799616939
# differential_evolution step 176: f(x)= 13065.251799616939
# differential_evolution step 177: f(x)= 13065.251799616939
# differential_evolution step 178: f(x)= 13065.251799616939
# differential_evolution step 179: f(x)= 13065.251799616939
# differential_evolution step 180: f(x)= 13060.398111968028
# differential_evolution step 181: f(x)= 13060.398111968028
# differential_evolution step 182: f(x)= 13057.879411099992
# differential_evolution step 183: f(x)= 13057.879411099992
# differential_evolution step 184: f(x)= 13057.879411099992
# differential_evolution step 185: f(x)= 13053.308226142739
# differential_evolution step 186: f(x)= 13053.308226142739
# differential_evolution step 187: f(x)= 13053.308226142739
# differential_evolution step 188: f(x)= 13053.308226142739
# differential_evolution step 189: f(x)= 13053.308226142739
# differential_evolution step 190: f(x)= 13053.308226142739
# differential_evolution step 191: f(x)= 13053.308226142739
# differential_evolution step 192: f(x)= 13053.308226142739
# differential_evolution step 193: f(x)= 13053.308226142739
# differential_evolution step 194: f(x)= 13053.308226142739
# differential_evolution step 195: f(x)= 13053.308226142739
# differential_evolution step 196: f(x)= 13053.308226142739
# differential_evolution step 197: f(x)= 13053.308226142739
# differential_evolution step 198: f(x)= 13053.308226142739
# differential_evolution step 199: f(x)= 13053.308226142739
# differential_evolution step 200: f(x)= 13053.308226142739
# differential_evolution step 201: f(x)= 13053.308226142739
# differential_evolution step 202: f(x)= 13053.308226142739
# differential_evolution step 203: f(x)= 13053.308226142739
# differential_evolution step 204: f(x)= 13053.308226142739
# differential_evolution step 205: f(x)= 13053.013153158516
# differential_evolution step 206: f(x)= 13053.013153158516
# differential_evolution step 207: f(x)= 13053.013153158516
# differential_evolution step 208: f(x)= 13053.013153158516
# differential_evolution step 209: f(x)= 13053.013153158516
# differential_evolution step 210: f(x)= 13052.216201397196
# differential_evolution step 211: f(x)= 13049.813126681913
# differential_evolution step 212: f(x)= 13049.813126681913
# differential_evolution step 213: f(x)= 13049.813126681913
# differential_evolution step 214: f(x)= 13049.813126681913
# differential_evolution step 215: f(x)= 13049.813126681913
# differential_evolution step 216: f(x)= 13049.813126681913
# differential_evolution step 217: f(x)= 13049.813126681913
# differential_evolution step 218: f(x)= 13049.813126681913
# differential_evolution step 219: f(x)= 13049.813126681913
# differential_evolution step 220: f(x)= 13049.813126681913
# differential_evolution step 221: f(x)= 13049.79442998139
# differential_evolution step 222: f(x)= 13049.734226545186
# differential_evolution step 223: f(x)= 13049.734226545186
# differential_evolution step 224: f(x)= 13049.734226545186
# differential_evolution step 225: f(x)= 13049.734226545186
# differential_evolution step 226: f(x)= 13049.734226545186
# differential_evolution step 227: f(x)= 13049.10615626408
# differential_evolution step 228: f(x)= 13049.10615626408
# differential_evolution step 229: f(x)= 13048.524374096105
# differential_evolution step 230: f(x)= 13048.524374096105
# differential_evolution step 231: f(x)= 13048.524374096105
# differential_evolution step 232: f(x)= 13048.524374096105
# differential_evolution step 233: f(x)= 13048.524374096105
# differential_evolution step 234: f(x)= 13048.524374096105
# differential_evolution step 235: f(x)= 13048.524374096105
# differential_evolution step 236: f(x)= 13048.320560631531
# differential_evolution step 237: f(x)= 13048.320560631531
# differential_evolution step 238: f(x)= 13048.320560631531
# differential_evolution step 239: f(x)= 13048.320560631531
# differential_evolution step 240: f(x)= 13048.320560631531
# differential_evolution step 241: f(x)= 13048.320560631531
# differential_evolution step 242: f(x)= 13048.320560631531
# differential_evolution step 243: f(x)= 13048.320560631531
# differential_evolution step 244: f(x)= 13048.320560631531
# differential_evolution step 245: f(x)= 13047.612029782742
# differential_evolution step 246: f(x)= 13047.612029782742
# differential_evolution step 247: f(x)= 13047.612029782742
# differential_evolution step 248: f(x)= 13047.612029782742
# differential_evolution step 249: f(x)= 13047.612029782742
# differential_evolution step 250: f(x)= 13047.612029782742
# differential_evolution step 251: f(x)= 13047.612029782742
# differential_evolution step 252: f(x)= 13047.612029782742
# differential_evolution step 253: f(x)= 13047.584849972789
# differential_evolution step 254: f(x)= 13047.584849972789
# differential_evolution step 255: f(x)= 13047.584849972789
# differential_evolution step 256: f(x)= 13047.584849972789
# differential_evolution step 257: f(x)= 13047.584849972789
# differential_evolution step 258: f(x)= 13047.581987117996
# differential_evolution step 259: f(x)= 13047.581987117996
# differential_evolution step 260: f(x)= 13047.483614504245
# differential_evolution step 261: f(x)= 13047.483614504245
# differential_evolution step 262: f(x)= 13047.170224116297
# differential_evolution step 263: f(x)= 13047.170224116297
# differential_evolution step 264: f(x)= 13047.170224116297
# differential_evolution step 265: f(x)= 13047.170224116297
# differential_evolution step 266: f(x)= 13047.170224116297
# differential_evolution step 267: f(x)= 13047.170224116297
# differential_evolution step 268: f(x)= 13047.170224116297
# differential_evolution step 269: f(x)= 13047.170224116297
# differential_evolution step 270: f(x)= 13047.170224116297
# differential_evolution step 271: f(x)= 13047.170224116297
# differential_evolution step 272: f(x)= 13047.170224116297
# differential_evolution step 273: f(x)= 13047.170224116297
# differential_evolution step 274: f(x)= 13047.170224116297
# differential_evolution step 275: f(x)= 13047.170224116297
# differential_evolution step 276: f(x)= 13047.170224116297
# differential_evolution step 277: f(x)= 13047.170224116297
# differential_evolution step 278: f(x)= 13047.084416602447
# differential_evolution step 279: f(x)= 13047.084416602447
# differential_evolution step 280: f(x)= 13047.016706560767
# differential_evolution step 281: f(x)= 13047.005846721167
# differential_evolution step 282: f(x)= 13047.005846721167
# differential_evolution step 283: f(x)= 13047.005846721167
# differential_evolution step 284: f(x)= 13047.005846721167
# differential_evolution step 285: f(x)= 13047.005846721167
# differential_evolution step 286: f(x)= 13047.005846721167
# differential_evolution step 287: f(x)= 13047.005846721167
# differential_evolution step 288: f(x)= 13047.005846721167
# differential_evolution step 289: f(x)= 13047.005846721167
# differential_evolution step 290: f(x)= 13047.005846721167
# differential_evolution step 291: f(x)= 13047.00204976756
# differential_evolution step 292: f(x)= 13047.00204976756
# differential_evolution step 293: f(x)= 13046.950094944557
# differential_evolution step 294: f(x)= 13046.950094944557
# differential_evolution step 295: f(x)= 13046.950094944557
# differential_evolution step 296: f(x)= 13046.936573265868
# differential_evolution step 297: f(x)= 13046.936573265868
# differential_evolution step 298: f(x)= 13046.92199950236
# differential_evolution step 299: f(x)= 13046.92199950236
# differential_evolution step 300: f(x)= 13046.92199950236
# differential_evolution step 301: f(x)= 13046.92199950236
# differential_evolution step 302: f(x)= 13046.903377218878
# differential_evolution step 303: f(x)= 13046.903377218878
# differential_evolution step 304: f(x)= 13046.903377218878
# differential_evolution step 305: f(x)= 13046.894515111284
# differential_evolution step 306: f(x)= 13046.89091588508
# differential_evolution step 307: f(x)= 13046.89091588508
# differential_evolution step 308: f(x)= 13046.89034912758
# differential_evolution step 309: f(x)= 13046.852023114667
# differential_evolution step 310: f(x)= 13046.848771326195
# differential_evolution step 311: f(x)= 13046.848771326195
# differential_evolution step 312: f(x)= 13046.848771326195
# differential_evolution step 313: f(x)= 13046.848771326195
# differential_evolution step 314: f(x)= 13046.848771326195
# differential_evolution step 315: f(x)= 13046.848771326195
# differential_evolution step 316: f(x)= 13046.848771326195
# differential_evolution step 317: f(x)= 13046.842590079306
# differential_evolution step 318: f(x)= 13046.835899569196
# differential_evolution step 319: f(x)= 13046.821569051717
# differential_evolution step 320: f(x)= 13046.821569051717
# differential_evolution step 321: f(x)= 13046.821569051717
# differential_evolution step 322: f(x)= 13046.821569051717
# differential_evolution step 323: f(x)= 13046.821569051717
# differential_evolution step 324: f(x)= 13046.819473579159
# differential_evolution step 325: f(x)= 13046.818318215435
# differential_evolution step 326: f(x)= 13046.818318215435
# differential_evolution step 327: f(x)= 13046.818318215435
# differential_evolution step 328: f(x)= 13046.818318215435
# differential_evolution step 329: f(x)= 13046.818318215435
# differential_evolution step 330: f(x)= 13046.818318215435
# differential_evolution step 331: f(x)= 13046.808009545784
# differential_evolution step 332: f(x)= 13046.808009545784
# differential_evolution step 333: f(x)= 13046.808009545784
# differential_evolution step 334: f(x)= 13046.808009545784
# differential_evolution step 335: f(x)= 13046.808009545784
# differential_evolution step 336: f(x)= 13046.808009545784
# differential_evolution step 337: f(x)= 13046.808009545784
# differential_evolution step 338: f(x)= 13046.808009545784
# differential_evolution step 339: f(x)= 13046.808009545784
# differential_evolution step 340: f(x)= 13046.808009545784
# differential_evolution step 341: f(x)= 13046.806068450693
# differential_evolution step 342: f(x)= 13046.806068450693
# differential_evolution step 343: f(x)= 13046.806068450693
# differential_evolution step 344: f(x)= 13046.80482540673
# differential_evolution step 345: f(x)= 13046.80482540673
# differential_evolution step 346: f(x)= 13046.80482540673
# differential_evolution step 347: f(x)= 13046.80482540673
# differential_evolution step 348: f(x)= 13046.803672241402
# differential_evolution step 349: f(x)= 13046.803672241402
# differential_evolution step 350: f(x)= 13046.803672241402
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.0000, r_e=50.0000, n=3.6462, x_0=40.3649
# Sérsic 2: I_e=1.0000, r_e=42.4566, n=2.6926, x_0=45.0000
# Sérsic 3: I_e=1.0000, r_e=12.5599, n=3.1386, x_0=58.9811
# Chi quadro minimo: 13046.795905748968
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 1450)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 1450)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_1, r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_1, covariance_continuum_1 = curve_fit(model_convolved, x_axes, radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1, bounds = bounds_list, maxfev=15000)

chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1,
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 3
#       1 lower_bounds, upper_bounds = zip(*bounds)
#       2 bounds_list = (list(lower_bounds), list(upper_bounds))
# ----> 3 params_curve_continuum_1, covariance_continuum_1 = curve_fit(model_convolved, x_axes, radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1, bounds = bounds_list, maxfev=15000)
#       5 chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1,
#       6     x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
#
# File ~\anaconda3\Lib\site-packages\scipy\optimize\_minpack_py.py:992, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     988 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     989                     **kwargs)
#     991 if not res.success:
# --> 992     raise RuntimeError("Optimal parameters not found: " + res.message)
#     994 infodict = dict(nfev=res.nfev, fvec=res.fun)
#     995 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, )
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, )
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
plot_diff(x_axes, best_params, radial_profile_continuum_2, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
params_curve_continuum_2, covariance_continuum_2 = curve_fit(model_convolved, x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2)#, maxfev=15000)
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
    radial_profile_error_continuum_2, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
def plot_curve(x_axes, params_curve, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 20)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, title = ""):
    y_fit = model_convolved(x_axes, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4]), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8]), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12]), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16]), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 20)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_3, r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(model_convolved, x_axes, radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3)

chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
    radial_profile_error_continuum_3, x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_diff(x_axes, params_curve_continuum_3, radial_profile_continuum_3, r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
