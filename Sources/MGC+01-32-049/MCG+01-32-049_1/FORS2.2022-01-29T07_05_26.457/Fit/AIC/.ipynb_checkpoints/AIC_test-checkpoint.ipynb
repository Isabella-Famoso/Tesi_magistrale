# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/MCG+01-32-049_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/MCG+01-32-049_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     377   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        58   (2094, 964)   float32

# %%
image_cut = image[52:172, 0:1890]
image_error_cut = image_error[52:172, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 52*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax=np.percentile(image_cut, 95))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.00309
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-32-049/MCG+01-32-049_1/PSF/Real_seeing_MGC+01-32-049.txt")
sigma = seeing[0]/2.35

# %%
l_HA
# Out:
# 6583.27967

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 120, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),  # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 59.21418911519675
# differential_evolution step 2: f(x)= 59.21418911519675
# differential_evolution step 3: f(x)= 50.322953613890895
# differential_evolution step 4: f(x)= 50.322953613890895
# differential_evolution step 5: f(x)= 50.322953613890895
# differential_evolution step 6: f(x)= 50.322953613890895
# differential_evolution step 7: f(x)= 50.322953613890895
# differential_evolution step 8: f(x)= 50.322953613890895
# differential_evolution step 9: f(x)= 50.322953613890895
# differential_evolution step 10: f(x)= 50.322953613890895
# differential_evolution step 11: f(x)= 36.49082722813409
# differential_evolution step 12: f(x)= 36.49082722813409
# differential_evolution step 13: f(x)= 30.665062983214916
# differential_evolution step 14: f(x)= 24.542537211473025
# differential_evolution step 15: f(x)= 24.542537211473025
# differential_evolution step 16: f(x)= 24.542537211473025
# differential_evolution step 17: f(x)= 24.542537211473025
# differential_evolution step 18: f(x)= 22.480434178558
# differential_evolution step 19: f(x)= 21.264379496979252
# differential_evolution step 20: f(x)= 21.087221421233124
# differential_evolution step 21: f(x)= 21.087221421233124
# differential_evolution step 22: f(x)= 21.087221421233124
# differential_evolution step 23: f(x)= 21.087221421233124
# differential_evolution step 24: f(x)= 19.222195330443608
# differential_evolution step 25: f(x)= 19.105126019180766
# differential_evolution step 26: f(x)= 18.611167398598575
# differential_evolution step 27: f(x)= 18.611167398598575
# differential_evolution step 28: f(x)= 18.094226278121504
# differential_evolution step 29: f(x)= 17.83286654294696
# differential_evolution step 30: f(x)= 17.83286654294696
# differential_evolution step 31: f(x)= 17.83286654294696
# differential_evolution step 32: f(x)= 17.654783705224787
# differential_evolution step 33: f(x)= 17.654783705224787
# differential_evolution step 34: f(x)= 17.654783705224787
# differential_evolution step 35: f(x)= 16.71471784666658
# differential_evolution step 36: f(x)= 16.46105360602789
# differential_evolution step 37: f(x)= 16.46105360602789
# differential_evolution step 38: f(x)= 16.46105360602789
# differential_evolution step 39: f(x)= 16.22390009601106
# differential_evolution step 40: f(x)= 16.205291820757225
# differential_evolution step 41: f(x)= 16.115069712509005
# differential_evolution step 42: f(x)= 16.115069712509005
# differential_evolution step 43: f(x)= 16.115069712509005
# differential_evolution step 44: f(x)= 16.00969099761939
# differential_evolution step 45: f(x)= 16.00969099761939
# differential_evolution step 46: f(x)= 15.982347226005379
# differential_evolution step 47: f(x)= 15.982347226005379
# differential_evolution step 48: f(x)= 15.908832991313819
# differential_evolution step 49: f(x)= 15.838450977976938
# differential_evolution step 50: f(x)= 15.79737291334012
# differential_evolution step 51: f(x)= 15.728791877486556
# differential_evolution step 52: f(x)= 15.712563875289787
# differential_evolution step 53: f(x)= 15.712563875289787
# differential_evolution step 54: f(x)= 15.50749049039532
# differential_evolution step 55: f(x)= 15.50749049039532
# differential_evolution step 56: f(x)= 15.426943013644493
# differential_evolution step 57: f(x)= 15.411260761346814
# differential_evolution step 58: f(x)= 15.411260761346814
# differential_evolution step 59: f(x)= 15.331838144021793
# differential_evolution step 60: f(x)= 15.331838144021793
# differential_evolution step 61: f(x)= 15.331838144021793
# differential_evolution step 62: f(x)= 15.331838144021793
# differential_evolution step 63: f(x)= 15.308465373959836
# differential_evolution step 64: f(x)= 15.300371749170397
# differential_evolution step 65: f(x)= 15.280286653335946
# differential_evolution step 66: f(x)= 15.260104860683589
# differential_evolution step 67: f(x)= 15.245480366157816
# differential_evolution step 68: f(x)= 15.196024137129747
# differential_evolution step 69: f(x)= 15.161108366981587
# differential_evolution step 70: f(x)= 15.161108366981587
# differential_evolution step 71: f(x)= 15.161108366981587
# differential_evolution step 72: f(x)= 15.161108366981587
# differential_evolution step 73: f(x)= 15.11563073260436
# differential_evolution step 74: f(x)= 15.079784305509277
# differential_evolution step 75: f(x)= 15.03125073983729
# differential_evolution step 76: f(x)= 15.03125073983729
# differential_evolution step 77: f(x)= 15.028473986705908
# differential_evolution step 78: f(x)= 15.028473986705908
# differential_evolution step 79: f(x)= 14.993563029331767
# differential_evolution step 80: f(x)= 14.993563029331767
# differential_evolution step 81: f(x)= 14.993563029331767
# differential_evolution step 82: f(x)= 14.957495731962318
# differential_evolution step 83: f(x)= 14.954949533495832
# differential_evolution step 84: f(x)= 14.954949533495832
# differential_evolution step 85: f(x)= 14.954949533495832
# differential_evolution step 86: f(x)= 14.94808028739639
# differential_evolution step 87: f(x)= 14.94808028739639
# differential_evolution step 88: f(x)= 14.94808028739639
# differential_evolution step 89: f(x)= 14.94808028739639
# differential_evolution step 90: f(x)= 14.94808028739639
# differential_evolution step 91: f(x)= 14.94808028739639
# differential_evolution step 92: f(x)= 14.943155712206242
# differential_evolution step 93: f(x)= 14.942635889264164
# differential_evolution step 94: f(x)= 14.942635889264164
# differential_evolution step 95: f(x)= 14.942635889264164
# differential_evolution step 96: f(x)= 14.942635889264164
# differential_evolution step 97: f(x)= 14.942635889264164
# differential_evolution step 98: f(x)= 14.942635889264164
# differential_evolution step 99: f(x)= 14.942544997906493
# differential_evolution step 100: f(x)= 14.942544997906493
# differential_evolution step 101: f(x)= 14.942017925547168
# differential_evolution step 102: f(x)= 14.942017925547168
# differential_evolution step 103: f(x)= 14.942017925547168
# differential_evolution step 104: f(x)= 14.94183765650017
# differential_evolution step 105: f(x)= 14.94183765650017
# differential_evolution step 106: f(x)= 14.94183765650017
# differential_evolution step 107: f(x)= 14.94135081498753
# differential_evolution step 108: f(x)= 14.94135081498753
# differential_evolution step 109: f(x)= 14.94135081498753
# differential_evolution step 110: f(x)= 14.94135081498753
# differential_evolution step 111: f(x)= 14.941206585593491
# differential_evolution step 112: f(x)= 14.941206585593491
# differential_evolution step 113: f(x)= 14.941206585593491
# differential_evolution step 114: f(x)= 14.941206585593491
# differential_evolution step 115: f(x)= 14.941206585593491
# differential_evolution step 116: f(x)= 14.941162068118935
# differential_evolution step 117: f(x)= 14.941162068118935
# differential_evolution step 118: f(x)= 14.941162068118935
# differential_evolution step 119: f(x)= 14.941162068118935
# differential_evolution step 120: f(x)= 14.941162068118935
# differential_evolution step 121: f(x)= 14.941162068118935
# differential_evolution step 122: f(x)= 14.941161466527285
# differential_evolution step 123: f(x)= 14.941161466527285
# differential_evolution step 124: f(x)= 14.941161466527285
# differential_evolution step 125: f(x)= 14.941157346329524
# differential_evolution step 126: f(x)= 14.941154340729259
# differential_evolution step 127: f(x)= 14.941154340729259
# differential_evolution step 128: f(x)= 14.941154340729259
# differential_evolution step 129: f(x)= 14.941154340729259
# differential_evolution step 130: f(x)= 14.94115430992255
# differential_evolution step 131: f(x)= 14.94115430992255
# differential_evolution step 132: f(x)= 14.941153467448853
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.08238207 49.999947    3.80964443 32.71979224]
# Chi quadro minimo: 14.941153456087012

# %%
# Plots:
aic = np.zeros(6)
bic = np.zeros(6)
chi_quadr = np.zeros(6)
chi_quadro = np.zeros(6)
red_chi = np.zeros(6)

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA, maxfev = 10000, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0774, r_e=49.1483, n=3.8541, x_0=32.7927
# [9.81096796e-02 3.88514496e+01 1.53436507e+00 2.86450720e-04]
# 360.47606215695544
# 368.82388824391194 0.0 379.62602912808364 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (68, 73)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 1264.1342866492973
# differential_evolution step 2: f(x)= 473.7909644550606
# differential_evolution step 3: f(x)= 114.65860198562353
# differential_evolution step 4: f(x)= 82.32696997529885
# differential_evolution step 5: f(x)= 82.32696997529885
# differential_evolution step 6: f(x)= 82.32696997529885
# differential_evolution step 7: f(x)= 82.32696997529885
# differential_evolution step 8: f(x)= 82.32696997529885
# differential_evolution step 9: f(x)= 82.32696997529885
# differential_evolution step 10: f(x)= 82.32696997529885
# differential_evolution step 11: f(x)= 16.176934532791513
# differential_evolution step 12: f(x)= 16.176934532791513
# differential_evolution step 13: f(x)= 16.176934532791513
# differential_evolution step 14: f(x)= 16.176934532791513
# differential_evolution step 15: f(x)= 16.176934532791513
# differential_evolution step 16: f(x)= 16.176934532791513
# differential_evolution step 17: f(x)= 16.176934532791513
# differential_evolution step 18: f(x)= 16.176934532791513
# differential_evolution step 19: f(x)= 16.176934532791513
# differential_evolution step 20: f(x)= 16.176934532791513
# differential_evolution step 21: f(x)= 16.176934532791513
# differential_evolution step 22: f(x)= 16.176934532791513
# differential_evolution step 23: f(x)= 11.992319683992374
# differential_evolution step 24: f(x)= 11.992319683992374
# differential_evolution step 25: f(x)= 11.992319683992374
# differential_evolution step 26: f(x)= 11.992319683992374
# differential_evolution step 27: f(x)= 11.992319683992374
# differential_evolution step 28: f(x)= 11.992319683992374
# differential_evolution step 29: f(x)= 11.992319683992374
# differential_evolution step 30: f(x)= 11.992319683992374
# differential_evolution step 31: f(x)= 11.992319683992374
# differential_evolution step 32: f(x)= 11.992319683992374
# differential_evolution step 33: f(x)= 9.719873618600694
# differential_evolution step 34: f(x)= 9.719873618600694
# differential_evolution step 35: f(x)= 9.719873618600694
# differential_evolution step 36: f(x)= 9.719873618600694
# differential_evolution step 37: f(x)= 9.719873618600694
# differential_evolution step 38: f(x)= 9.719873618600694
# differential_evolution step 39: f(x)= 9.719873618600694
# differential_evolution step 40: f(x)= 9.719873618600694
# differential_evolution step 41: f(x)= 9.719873618600694
# differential_evolution step 42: f(x)= 9.719873618600694
# differential_evolution step 43: f(x)= 8.277778871193274
# differential_evolution step 44: f(x)= 8.277778871193274
# differential_evolution step 45: f(x)= 7.844920960087233
# differential_evolution step 46: f(x)= 7.844920960087233
# differential_evolution step 47: f(x)= 7.6049826205416515
# differential_evolution step 48: f(x)= 7.55984043444804
# differential_evolution step 49: f(x)= 7.55984043444804
# differential_evolution step 50: f(x)= 7.55984043444804
# differential_evolution step 51: f(x)= 7.323247729153154
# differential_evolution step 52: f(x)= 6.988815163176815
# differential_evolution step 53: f(x)= 6.8066918410716335
# differential_evolution step 54: f(x)= 6.716261892690332
# differential_evolution step 55: f(x)= 6.716261892690332
# differential_evolution step 56: f(x)= 6.336616754645611
# differential_evolution step 57: f(x)= 5.95876747311853
# differential_evolution step 58: f(x)= 5.95876747311853
# differential_evolution step 59: f(x)= 5.95876747311853
# differential_evolution step 60: f(x)= 5.95876747311853
# differential_evolution step 61: f(x)= 5.83672789510545
# differential_evolution step 62: f(x)= 5.83672789510545
# differential_evolution step 63: f(x)= 5.83672789510545
# differential_evolution step 64: f(x)= 5.83672789510545
# differential_evolution step 65: f(x)= 5.744802560480853
# differential_evolution step 66: f(x)= 5.744802560480853
# differential_evolution step 67: f(x)= 5.402412136591453
# differential_evolution step 68: f(x)= 5.402412136591453
# differential_evolution step 69: f(x)= 5.402412136591453
# differential_evolution step 70: f(x)= 5.402412136591453
# differential_evolution step 71: f(x)= 4.9214135228189
# differential_evolution step 72: f(x)= 4.9214135228189
# differential_evolution step 73: f(x)= 4.9214135228189
# differential_evolution step 74: f(x)= 4.9214135228189
# differential_evolution step 75: f(x)= 4.9214135228189
# differential_evolution step 76: f(x)= 4.9214135228189
# differential_evolution step 77: f(x)= 4.88077225498282
# differential_evolution step 78: f(x)= 4.88077225498282
# differential_evolution step 79: f(x)= 4.88077225498282
# differential_evolution step 80: f(x)= 4.88077225498282
# differential_evolution step 81: f(x)= 4.88077225498282
# differential_evolution step 82: f(x)= 4.88077225498282
# differential_evolution step 83: f(x)= 4.88077225498282
# differential_evolution step 84: f(x)= 4.88077225498282
# differential_evolution step 85: f(x)= 4.88077225498282
# differential_evolution step 86: f(x)= 4.88077225498282
# differential_evolution step 87: f(x)= 4.88077225498282
# differential_evolution step 88: f(x)= 4.88077225498282
# differential_evolution step 89: f(x)= 4.88077225498282
# differential_evolution step 90: f(x)= 4.863467403570171
# differential_evolution step 91: f(x)= 4.863467403570171
# differential_evolution step 92: f(x)= 4.8103713767155645
# differential_evolution step 93: f(x)= 4.8103713767155645
# differential_evolution step 94: f(x)= 4.8103713767155645
# differential_evolution step 95: f(x)= 4.8103713767155645
# differential_evolution step 96: f(x)= 4.7349342100453455
# differential_evolution step 97: f(x)= 4.7349342100453455
# differential_evolution step 98: f(x)= 4.7349342100453455
# differential_evolution step 99: f(x)= 4.671953719245794
# differential_evolution step 100: f(x)= 4.671953719245794
# differential_evolution step 101: f(x)= 4.671953719245794
# differential_evolution step 102: f(x)= 4.671953719245794
# differential_evolution step 103: f(x)= 4.671953719245794
# differential_evolution step 104: f(x)= 4.65635851928762
# differential_evolution step 105: f(x)= 4.65635851928762
# differential_evolution step 106: f(x)= 4.65635851928762
# differential_evolution step 107: f(x)= 4.65635851928762
# differential_evolution step 108: f(x)= 4.65635851928762
# differential_evolution step 109: f(x)= 4.642528241008838
# differential_evolution step 110: f(x)= 4.642528241008838
# differential_evolution step 111: f(x)= 4.642528241008838
# differential_evolution step 112: f(x)= 4.615873729151186
# differential_evolution step 113: f(x)= 4.615726000302493
# differential_evolution step 114: f(x)= 4.610155149936584
# differential_evolution step 115: f(x)= 4.610155149936584
# differential_evolution step 116: f(x)= 4.604226226780317
# differential_evolution step 117: f(x)= 4.604226226780317
# differential_evolution step 118: f(x)= 4.604226226780317
# differential_evolution step 119: f(x)= 4.604226226780317
# differential_evolution step 120: f(x)= 4.604226226780317
# differential_evolution step 121: f(x)= 4.604226226780317
# differential_evolution step 122: f(x)= 4.604226226780317
# differential_evolution step 123: f(x)= 4.604226226780317
# differential_evolution step 124: f(x)= 4.604226226780317
# differential_evolution step 125: f(x)= 4.604223121902092
# differential_evolution step 126: f(x)= 4.604223121902092
# differential_evolution step 127: f(x)= 4.604223121902092
# differential_evolution step 128: f(x)= 4.588163004089497
# differential_evolution step 129: f(x)= 4.588163004089497
# differential_evolution step 130: f(x)= 4.584715200719844
# differential_evolution step 131: f(x)= 4.584715200719844
# differential_evolution step 132: f(x)= 4.584715200719844
# differential_evolution step 133: f(x)= 4.584715200719844
# differential_evolution step 134: f(x)= 4.584715200719844
# differential_evolution step 135: f(x)= 4.584715200719844
# differential_evolution step 136: f(x)= 4.584715200719844
# differential_evolution step 137: f(x)= 4.584715200719844
# differential_evolution step 138: f(x)= 4.584715200719844
# differential_evolution step 139: f(x)= 4.57660156368215
# differential_evolution step 140: f(x)= 4.57660156368215
# differential_evolution step 141: f(x)= 4.576469780328248
# differential_evolution step 142: f(x)= 4.562110264108805
# differential_evolution step 143: f(x)= 4.562110264108805
# differential_evolution step 144: f(x)= 4.562110264108805
# differential_evolution step 145: f(x)= 4.560178684684976
# differential_evolution step 146: f(x)= 4.560178684684976
# differential_evolution step 147: f(x)= 4.550441231141976
# differential_evolution step 148: f(x)= 4.550441231141976
# differential_evolution step 149: f(x)= 4.550441231141976
# differential_evolution step 150: f(x)= 4.550005365948569
# differential_evolution step 151: f(x)= 4.550005365948569
# differential_evolution step 152: f(x)= 4.54789887566304
# differential_evolution step 153: f(x)= 4.542048003912276
# differential_evolution step 154: f(x)= 4.542048003912276
# differential_evolution step 155: f(x)= 4.542048003912276
# differential_evolution step 156: f(x)= 4.542048003912276
# differential_evolution step 157: f(x)= 4.541746223223896
# differential_evolution step 158: f(x)= 4.540600190165242
# differential_evolution step 159: f(x)= 4.540600190165242
# differential_evolution step 160: f(x)= 4.540600190165242
# differential_evolution step 161: f(x)= 4.540600190165242
# differential_evolution step 162: f(x)= 4.536835237020888
# differential_evolution step 163: f(x)= 4.53533064837373
# differential_evolution step 164: f(x)= 4.533375145914481
# differential_evolution step 165: f(x)= 4.533375145914481
# differential_evolution step 166: f(x)= 4.533375145914481
# differential_evolution step 167: f(x)= 4.533375145914481
# differential_evolution step 168: f(x)= 4.533375145914481
# differential_evolution step 169: f(x)= 4.533375145914481
# differential_evolution step 170: f(x)= 4.533375145914481
# differential_evolution step 171: f(x)= 4.533375145914481
# differential_evolution step 172: f(x)= 4.533375145914481
# differential_evolution step 173: f(x)= 4.533375145914481
# differential_evolution step 174: f(x)= 4.533375145914481
# differential_evolution step 175: f(x)= 4.532180638868679
# differential_evolution step 176: f(x)= 4.532039436889518
# differential_evolution step 177: f(x)= 4.530727134941934
# differential_evolution step 178: f(x)= 4.530727134941934
# differential_evolution step 179: f(x)= 4.530727134941934
# differential_evolution step 180: f(x)= 4.530727134941934
# differential_evolution step 181: f(x)= 4.529555537228859
# differential_evolution step 182: f(x)= 4.529555537228859
# differential_evolution step 183: f(x)= 4.529555537228859
# differential_evolution step 184: f(x)= 4.529555537228859
# differential_evolution step 185: f(x)= 4.529555537228859
# differential_evolution step 186: f(x)= 4.529555537228859
# differential_evolution step 187: f(x)= 4.529555537228859
# differential_evolution step 188: f(x)= 4.529555537228859
# differential_evolution step 189: f(x)= 4.529555537228859
# differential_evolution step 190: f(x)= 4.529555537228859
# differential_evolution step 191: f(x)= 4.529555537228859
# differential_evolution step 192: f(x)= 4.529555537228859
# differential_evolution step 193: f(x)= 4.529555537228859
# differential_evolution step 194: f(x)= 4.529555537228859
# differential_evolution step 195: f(x)= 4.529555537228859
# differential_evolution step 196: f(x)= 4.529555537228859
# differential_evolution step 197: f(x)= 4.529555537228859
# differential_evolution step 198: f(x)= 4.529555537228859
# differential_evolution step 199: f(x)= 4.529555537228859
# differential_evolution step 200: f(x)= 4.529555537228859
# differential_evolution step 201: f(x)= 4.529555537228859
# differential_evolution step 202: f(x)= 4.529555537228859
# differential_evolution step 203: f(x)= 4.529555537228859
# differential_evolution step 204: f(x)= 4.529555537228859
# differential_evolution step 205: f(x)= 4.529555537228859
# differential_evolution step 206: f(x)= 4.52935168327252
# differential_evolution step 207: f(x)= 4.52935168327252
# differential_evolution step 208: f(x)= 4.52935168327252
# differential_evolution step 209: f(x)= 4.52935168327252
# differential_evolution step 210: f(x)= 4.529327307979944
# differential_evolution step 211: f(x)= 4.529327307979944
# differential_evolution step 212: f(x)= 4.528695186526365
# differential_evolution step 213: f(x)= 4.528695186526365
# differential_evolution step 214: f(x)= 4.528695186526365
# differential_evolution step 215: f(x)= 4.528511472858812
# differential_evolution step 216: f(x)= 4.528490050179616
# differential_evolution step 217: f(x)= 4.528490050179616
# differential_evolution step 218: f(x)= 4.528490050179616
# differential_evolution step 219: f(x)= 4.528490050179616
# differential_evolution step 220: f(x)= 4.528490050179616
# differential_evolution step 221: f(x)= 4.5274514604153415
# differential_evolution step 222: f(x)= 4.5274514604153415
# differential_evolution step 223: f(x)= 4.5274514604153415
# differential_evolution step 224: f(x)= 4.5274514604153415
# differential_evolution step 225: f(x)= 4.5274514604153415
# differential_evolution step 226: f(x)= 4.5274514604153415
# differential_evolution step 227: f(x)= 4.5274514604153415
# differential_evolution step 228: f(x)= 4.5274514604153415
# differential_evolution step 229: f(x)= 4.5274514604153415
# differential_evolution step 230: f(x)= 4.5274514604153415
# differential_evolution step 231: f(x)= 4.5274514604153415
# differential_evolution step 232: f(x)= 4.5274514604153415
# differential_evolution step 233: f(x)= 4.527264937754477
# differential_evolution step 234: f(x)= 4.527264937754477
# differential_evolution step 235: f(x)= 4.527264937754477
# differential_evolution step 236: f(x)= 4.527264937754477
# differential_evolution step 237: f(x)= 4.527264937754477
# differential_evolution step 238: f(x)= 4.527264937754477
# differential_evolution step 239: f(x)= 4.527264937754477
# differential_evolution step 240: f(x)= 4.527264937754477
# differential_evolution step 241: f(x)= 4.527264937754477
# differential_evolution step 242: f(x)= 4.527233789043198
# differential_evolution step 243: f(x)= 4.527233789043198
# differential_evolution step 244: f(x)= 4.527233789043198
# differential_evolution step 245: f(x)= 4.5270510891296905
# differential_evolution step 246: f(x)= 4.5270510891296905
# differential_evolution step 247: f(x)= 4.5270510891296905
# differential_evolution step 248: f(x)= 4.5270510891296905
# differential_evolution step 249: f(x)= 4.5270510891296905
# differential_evolution step 250: f(x)= 4.5270510891296905
# differential_evolution step 251: f(x)= 4.5270510891296905
# differential_evolution step 252: f(x)= 4.5270510891296905
# differential_evolution step 253: f(x)= 4.5270510891296905
# differential_evolution step 254: f(x)= 4.5270510891296905
# differential_evolution step 255: f(x)= 4.5270510891296905
# differential_evolution step 256: f(x)= 4.5270510891296905
# differential_evolution step 257: f(x)= 4.5270510891296905
# differential_evolution step 258: f(x)= 4.5270510891296905
# differential_evolution step 259: f(x)= 4.5270510891296905
# differential_evolution step 260: f(x)= 4.5270510891296905
# differential_evolution step 261: f(x)= 4.5270510891296905
# differential_evolution step 262: f(x)= 4.5270510891296905
# differential_evolution step 263: f(x)= 4.5270510891296905
# differential_evolution step 264: f(x)= 4.5270510891296905
# differential_evolution step 265: f(x)= 4.5270393393184625
# differential_evolution step 266: f(x)= 4.5270393393184625
# differential_evolution step 267: f(x)= 4.5270393393184625
# differential_evolution step 268: f(x)= 4.5270393393184625
# differential_evolution step 269: f(x)= 4.527015590095039
# differential_evolution step 270: f(x)= 4.527015590095039
# differential_evolution step 271: f(x)= 4.527015590095039
# differential_evolution step 272: f(x)= 4.527015590095039
# differential_evolution step 273: f(x)= 4.527015590095039
# differential_evolution step 274: f(x)= 4.527015590095039
# differential_evolution step 275: f(x)= 4.526886500696355
# differential_evolution step 276: f(x)= 4.526886500696355
# differential_evolution step 277: f(x)= 4.526886500696355
# differential_evolution step 278: f(x)= 4.526886500696355
# differential_evolution step 279: f(x)= 4.526886500696355
# differential_evolution step 280: f(x)= 4.526886500696355
# differential_evolution step 281: f(x)= 4.526886500696355
# differential_evolution step 282: f(x)= 4.526886500696355
# differential_evolution step 283: f(x)= 4.526886500696355
# differential_evolution step 284: f(x)= 4.526886500696355
# differential_evolution step 285: f(x)= 4.526886500696355
# differential_evolution step 286: f(x)= 4.52684515970439
# differential_evolution step 287: f(x)= 4.52684515970439
# differential_evolution step 288: f(x)= 4.52684515970439
# differential_evolution step 289: f(x)= 4.52684515970439
# differential_evolution step 290: f(x)= 4.52684515970439
# differential_evolution step 291: f(x)= 4.52684515970439
# differential_evolution step 292: f(x)= 4.52684515970439
# differential_evolution step 293: f(x)= 4.52684515970439
# differential_evolution step 294: f(x)= 4.526830851229077
# differential_evolution step 295: f(x)= 4.526830851229077
# differential_evolution step 296: f(x)= 4.526830851229077
# differential_evolution step 297: f(x)= 4.526830851229077
# differential_evolution step 298: f(x)= 4.526830851229077
# differential_evolution step 299: f(x)= 4.526763050638044
# differential_evolution step 300: f(x)= 4.526763050638044
# differential_evolution step 301: f(x)= 4.526763050638044
# differential_evolution step 302: f(x)= 4.526763050638044
# differential_evolution step 303: f(x)= 4.526763050638044
# differential_evolution step 304: f(x)= 4.526763050638044
# differential_evolution step 305: f(x)= 4.526763050638044
# differential_evolution step 306: f(x)= 4.526763050638044
# differential_evolution step 307: f(x)= 4.526763050638044
# differential_evolution step 308: f(x)= 4.526763050638044
# differential_evolution step 309: f(x)= 4.526731518444517
# differential_evolution step 310: f(x)= 4.526731518444517
# differential_evolution step 311: f(x)= 4.526731518444517
# differential_evolution step 312: f(x)= 4.526731518444517
# differential_evolution step 313: f(x)= 4.526689129601739
# differential_evolution step 314: f(x)= 4.526689129601739
# differential_evolution step 315: f(x)= 4.526689129601739
# differential_evolution step 316: f(x)= 4.526689129601739
# differential_evolution step 317: f(x)= 4.526689129601739
# differential_evolution step 318: f(x)= 4.526689129601739
# differential_evolution step 319: f(x)= 4.526676177503946
# differential_evolution step 320: f(x)= 4.526676177503946
# differential_evolution step 321: f(x)= 4.526676177503946
# differential_evolution step 322: f(x)= 4.52666740138155
# differential_evolution step 323: f(x)= 4.5266615861301025
# differential_evolution step 324: f(x)= 4.526608735661295
# differential_evolution step 325: f(x)= 4.526608735661295
# differential_evolution step 326: f(x)= 4.526608735661295
# differential_evolution step 327: f(x)= 4.526608735661295
# differential_evolution step 328: f(x)= 4.526608735661295
# differential_evolution step 329: f(x)= 4.5265985760056715
# differential_evolution step 330: f(x)= 4.5265985760056715
# differential_evolution step 331: f(x)= 4.5265985760056715
# differential_evolution step 332: f(x)= 4.5265985760056715
# differential_evolution step 333: f(x)= 4.5265985760056715
# differential_evolution step 334: f(x)= 4.5265985760056715
# differential_evolution step 335: f(x)= 4.5265985760056715
# differential_evolution step 336: f(x)= 4.5265985760056715
# differential_evolution step 337: f(x)= 4.52659240270942
# differential_evolution step 338: f(x)= 4.526576739218902
# differential_evolution step 339: f(x)= 4.526576739218902
# differential_evolution step 340: f(x)= 4.526576739218902
# differential_evolution step 341: f(x)= 4.526576739218902
# differential_evolution step 342: f(x)= 4.5265641216566195
# differential_evolution step 343: f(x)= 4.5265641216566195
# differential_evolution step 344: f(x)= 4.5265641216566195
# differential_evolution step 345: f(x)= 4.5265641216566195
# differential_evolution step 346: f(x)= 4.526560559405205
# differential_evolution step 347: f(x)= 4.526560559405205
# differential_evolution step 348: f(x)= 4.526560559405205
# differential_evolution step 349: f(x)= 4.526560559405205
# differential_evolution step 350: f(x)= 4.526560559405205
# differential_evolution step 351: f(x)= 4.526560559405205
# differential_evolution step 352: f(x)= 4.526560559405205
# differential_evolution step 353: f(x)= 4.526560559405205
# differential_evolution step 354: f(x)= 4.526560559405205
# differential_evolution step 355: f(x)= 4.526560559405205
# differential_evolution step 356: f(x)= 4.526560559405205
# differential_evolution step 357: f(x)= 4.526560559405205
# differential_evolution step 358: f(x)= 4.526554501402943
# differential_evolution step 359: f(x)= 4.526554501402943
# differential_evolution step 360: f(x)= 4.526554501402943
# differential_evolution step 361: f(x)= 4.526554501402943
# differential_evolution step 362: f(x)= 4.526554501402943
# differential_evolution step 363: f(x)= 4.526554501402943
# differential_evolution step 364: f(x)= 4.526544437508155
# differential_evolution step 365: f(x)= 4.526544437508155
# differential_evolution step 366: f(x)= 4.526544437508155
# differential_evolution step 367: f(x)= 4.526544437508155
# differential_evolution step 368: f(x)= 4.526544437508155
# differential_evolution step 369: f(x)= 4.526544437508155
# differential_evolution step 370: f(x)= 4.526544437508155
# differential_evolution step 371: f(x)= 4.526544437508155
# differential_evolution step 372: f(x)= 4.526544437508155
# differential_evolution step 373: f(x)= 4.5265393358745865
# differential_evolution step 374: f(x)= 4.5265393358745865
# differential_evolution step 375: f(x)= 4.5265393358745865
# differential_evolution step 376: f(x)= 4.5265393358745865
# differential_evolution step 377: f(x)= 4.526535008971401
# differential_evolution step 378: f(x)= 4.526535008971401
# differential_evolution step 379: f(x)= 4.526535008971401
# differential_evolution step 380: f(x)= 4.526535008971401
# differential_evolution step 381: f(x)= 4.526533636891433
# differential_evolution step 382: f(x)= 4.526533636891433
# differential_evolution step 383: f(x)= 4.526533636891433
# differential_evolution step 384: f(x)= 4.526533636891433
# differential_evolution step 385: f(x)= 4.526533636891433
# differential_evolution step 386: f(x)= 4.526533636891433
# differential_evolution step 387: f(x)= 4.526529537356878
# differential_evolution step 388: f(x)= 4.526529537356878
# differential_evolution step 389: f(x)= 4.526529537356878
# differential_evolution step 390: f(x)= 4.526529537356878
# differential_evolution step 391: f(x)= 4.526529537356878
# differential_evolution step 392: f(x)= 4.526529537356878
# differential_evolution step 393: f(x)= 4.526529537356878
# differential_evolution step 394: f(x)= 4.526529537356878
# differential_evolution step 395: f(x)= 4.526529537356878
# differential_evolution step 396: f(x)= 4.526529537356878
# differential_evolution step 397: f(x)= 4.526529537356878
# differential_evolution step 398: f(x)= 4.526529537356878
# differential_evolution step 399: f(x)= 4.526529537356878
# differential_evolution step 400: f(x)= 4.526529537356878
# differential_evolution step 401: f(x)= 4.526529537356878
# differential_evolution step 402: f(x)= 4.526527914441672
# differential_evolution step 403: f(x)= 4.526527914441672
# differential_evolution step 404: f(x)= 4.526527115879064
# differential_evolution step 405: f(x)= 4.526527115879064
# differential_evolution step 406: f(x)= 4.526525361733206
# differential_evolution step 407: f(x)= 4.526525361733206
# differential_evolution step 408: f(x)= 4.526525361733206
# differential_evolution step 409: f(x)= 4.526525361733206
# differential_evolution step 410: f(x)= 4.526525361733206
# differential_evolution step 411: f(x)= 4.526525361733206
# differential_evolution step 412: f(x)= 4.526524194417
# differential_evolution step 413: f(x)= 4.526524194417
# differential_evolution step 414: f(x)= 4.526524194417
# differential_evolution step 415: f(x)= 4.526523311847697
# differential_evolution step 416: f(x)= 4.526523311847697
# differential_evolution step 417: f(x)= 4.526523311847697
# differential_evolution step 418: f(x)= 4.526523311847697
# differential_evolution step 419: f(x)= 4.526522577238298
# differential_evolution step 420: f(x)= 4.526522577238298
# differential_evolution step 421: f(x)= 4.526522577238298
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [4.46697044e-01 1.37672936e+01 2.54202564e+00 3.27218314e+01
#  2.54609466e-02 4.99998030e+01 2.74162269e+00 7.01680420e+01]
# Chi quadro minimo: 4.526522577238298

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1828, r_e=23.7455, n=3.3234, x_0=32.8039
# Sérsic 2: I_e=0.0037, r_e=208.9951, n=4.0955, x_0=70.1680
# [7.74613797e-02 6.85099569e+00 3.63504292e-01 5.71383012e-02
#  1.50591744e-02 6.25873905e+02 3.51113175e+00 4.32022876e-04]
# 101.78952246190072
# 119.08681975919801 101.78952246190072 140.0894564041571 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (68, 73),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 2549.680254977525
# differential_evolution step 2: f(x)= 2549.680254977525
# differential_evolution step 3: f(x)= 1242.5530808742062
# differential_evolution step 4: f(x)= 811.4541274621745
# differential_evolution step 5: f(x)= 225.0663604118477
# differential_evolution step 6: f(x)= 225.0663604118477
# differential_evolution step 7: f(x)= 134.07733848510946
# differential_evolution step 8: f(x)= 117.15401114256646
# differential_evolution step 9: f(x)= 77.86874768152713
# differential_evolution step 10: f(x)= 77.86874768152713
# differential_evolution step 11: f(x)= 77.86874768152713
# differential_evolution step 12: f(x)= 77.86874768152713
# differential_evolution step 13: f(x)= 77.86874768152713
# differential_evolution step 14: f(x)= 35.07204863170927
# differential_evolution step 15: f(x)= 35.07204863170927
# differential_evolution step 16: f(x)= 35.07204863170927
# differential_evolution step 17: f(x)= 35.07204863170927
# differential_evolution step 18: f(x)= 35.07204863170927
# differential_evolution step 19: f(x)= 19.580283240999172
# differential_evolution step 20: f(x)= 19.580283240999172
# differential_evolution step 21: f(x)= 19.580283240999172
# differential_evolution step 22: f(x)= 19.580283240999172
# differential_evolution step 23: f(x)= 19.580283240999172
# differential_evolution step 24: f(x)= 19.580283240999172
# differential_evolution step 25: f(x)= 19.580283240999172
# differential_evolution step 26: f(x)= 17.044957463601786
# differential_evolution step 27: f(x)= 17.044957463601786
# differential_evolution step 28: f(x)= 17.044957463601786
# differential_evolution step 29: f(x)= 17.044957463601786
# differential_evolution step 30: f(x)= 17.044957463601786
# differential_evolution step 31: f(x)= 17.044957463601786
# differential_evolution step 32: f(x)= 17.044957463601786
# differential_evolution step 33: f(x)= 17.044957463601786
# differential_evolution step 34: f(x)= 17.044957463601786
# differential_evolution step 35: f(x)= 17.044957463601786
# differential_evolution step 36: f(x)= 17.044957463601786
# differential_evolution step 37: f(x)= 17.044957463601786
# differential_evolution step 38: f(x)= 12.439406791513253
# differential_evolution step 39: f(x)= 12.439406791513253
# differential_evolution step 40: f(x)= 12.439406791513253
# differential_evolution step 41: f(x)= 12.439406791513253
# differential_evolution step 42: f(x)= 12.439406791513253
# differential_evolution step 43: f(x)= 12.439406791513253
# differential_evolution step 44: f(x)= 12.439406791513253
# differential_evolution step 45: f(x)= 12.392360952906987
# differential_evolution step 46: f(x)= 12.392360952906987
# differential_evolution step 47: f(x)= 12.392360952906987
# differential_evolution step 48: f(x)= 12.392360952906987
# differential_evolution step 49: f(x)= 11.879736857982433
# differential_evolution step 50: f(x)= 11.879736857982433
# differential_evolution step 51: f(x)= 11.879736857982433
# differential_evolution step 52: f(x)= 11.875471688028718
# differential_evolution step 53: f(x)= 10.196910682903516
# differential_evolution step 54: f(x)= 9.189185200950208
# differential_evolution step 55: f(x)= 9.189185200950208
# differential_evolution step 56: f(x)= 9.189185200950208
# differential_evolution step 57: f(x)= 8.711029787333484
# differential_evolution step 58: f(x)= 8.711029787333484
# differential_evolution step 59: f(x)= 8.711029787333484
# differential_evolution step 60: f(x)= 8.477435899595196
# differential_evolution step 61: f(x)= 8.477435899595196
# differential_evolution step 62: f(x)= 8.477435899595196
# differential_evolution step 63: f(x)= 8.477435899595196
# differential_evolution step 64: f(x)= 8.477435899595196
# differential_evolution step 65: f(x)= 8.275465549253965
# differential_evolution step 66: f(x)= 7.209124532608561
# differential_evolution step 67: f(x)= 6.665954533296145
# differential_evolution step 68: f(x)= 6.665954533296145
# differential_evolution step 69: f(x)= 5.188823741446864
# differential_evolution step 70: f(x)= 5.188823741446864
# differential_evolution step 71: f(x)= 5.188823741446864
# differential_evolution step 72: f(x)= 5.188823741446864
# differential_evolution step 73: f(x)= 5.188823741446864
# differential_evolution step 74: f(x)= 5.188823741446864
# differential_evolution step 75: f(x)= 5.188823741446864
# differential_evolution step 76: f(x)= 5.188823741446864
# differential_evolution step 77: f(x)= 5.188823741446864
# differential_evolution step 78: f(x)= 5.188823741446864
# differential_evolution step 79: f(x)= 5.188823741446864
# differential_evolution step 80: f(x)= 5.188823741446864
# differential_evolution step 81: f(x)= 5.188823741446864
# differential_evolution step 82: f(x)= 5.188823741446864
# differential_evolution step 83: f(x)= 4.838246600641694
# differential_evolution step 84: f(x)= 4.838246600641694
# differential_evolution step 85: f(x)= 4.838246600641694
# differential_evolution step 86: f(x)= 4.838246600641694
# differential_evolution step 87: f(x)= 4.838246600641694
# differential_evolution step 88: f(x)= 4.634597831082141
# differential_evolution step 89: f(x)= 4.634597831082141
# differential_evolution step 90: f(x)= 4.634597831082141
# differential_evolution step 91: f(x)= 4.4466684169774116
# differential_evolution step 92: f(x)= 4.4466684169774116
# differential_evolution step 93: f(x)= 4.4466684169774116
# differential_evolution step 94: f(x)= 4.4154711075190605
# differential_evolution step 95: f(x)= 4.4154711075190605
# differential_evolution step 96: f(x)= 4.4154711075190605
# differential_evolution step 97: f(x)= 4.151705905947278
# differential_evolution step 98: f(x)= 4.151705905947278
# differential_evolution step 99: f(x)= 4.151705905947278
# differential_evolution step 100: f(x)= 4.151705905947278
# differential_evolution step 101: f(x)= 4.110001715164232
# differential_evolution step 102: f(x)= 4.110001715164232
# differential_evolution step 103: f(x)= 4.110001715164232
# differential_evolution step 104: f(x)= 4.110001715164232
# differential_evolution step 105: f(x)= 4.110001715164232
# differential_evolution step 106: f(x)= 4.110001715164232
# differential_evolution step 107: f(x)= 4.109033257880752
# differential_evolution step 108: f(x)= 4.109033257880752
# differential_evolution step 109: f(x)= 4.109033257880752
# differential_evolution step 110: f(x)= 4.109033257880752
# differential_evolution step 111: f(x)= 4.109033257880752
# differential_evolution step 112: f(x)= 4.109033257880752
# differential_evolution step 113: f(x)= 4.109033257880752
# differential_evolution step 114: f(x)= 4.109033257880752
# differential_evolution step 115: f(x)= 4.109033257880752
# differential_evolution step 116: f(x)= 4.109033257880752
# differential_evolution step 117: f(x)= 3.9573143717298196
# differential_evolution step 118: f(x)= 3.9573143717298196
# differential_evolution step 119: f(x)= 3.9573143717298196
# differential_evolution step 120: f(x)= 3.9573143717298196
# differential_evolution step 121: f(x)= 3.9573143717298196
# differential_evolution step 122: f(x)= 3.9573143717298196
# differential_evolution step 123: f(x)= 3.9573143717298196
# differential_evolution step 124: f(x)= 3.9573143717298196
# differential_evolution step 125: f(x)= 3.9573143717298196
# differential_evolution step 126: f(x)= 3.896631284279053
# differential_evolution step 127: f(x)= 3.896631284279053
# differential_evolution step 128: f(x)= 3.8933469061628303
# differential_evolution step 129: f(x)= 3.8933469061628303
# differential_evolution step 130: f(x)= 3.8047379721363925
# differential_evolution step 131: f(x)= 3.8047379721363925
# differential_evolution step 132: f(x)= 3.8047379721363925
# differential_evolution step 133: f(x)= 3.8047379721363925
# differential_evolution step 134: f(x)= 3.8047379721363925
# differential_evolution step 135: f(x)= 3.8047379721363925
# differential_evolution step 136: f(x)= 3.8047379721363925
# differential_evolution step 137: f(x)= 3.8047379721363925
# differential_evolution step 138: f(x)= 3.8047379721363925
# differential_evolution step 139: f(x)= 3.8047379721363925
# differential_evolution step 140: f(x)= 3.8047379721363925
# differential_evolution step 141: f(x)= 3.8047379721363925
# differential_evolution step 142: f(x)= 3.8047379721363925
# differential_evolution step 143: f(x)= 3.8047379721363925
# differential_evolution step 144: f(x)= 3.8047379721363925
# differential_evolution step 145: f(x)= 3.8047379721363925
# differential_evolution step 146: f(x)= 3.8047379721363925
# differential_evolution step 147: f(x)= 3.8047379721363925
# differential_evolution step 148: f(x)= 3.8047379721363925
# differential_evolution step 149: f(x)= 3.8047379721363925
# differential_evolution step 150: f(x)= 3.720398304148154
# differential_evolution step 151: f(x)= 3.7027495043498275
# differential_evolution step 152: f(x)= 3.7027495043498275
# differential_evolution step 153: f(x)= 3.7027495043498275
# differential_evolution step 154: f(x)= 3.7027495043498275
# differential_evolution step 155: f(x)= 3.7027495043498275
# differential_evolution step 156: f(x)= 3.7027495043498275
# differential_evolution step 157: f(x)= 3.7027495043498275
# differential_evolution step 158: f(x)= 3.7027495043498275
# differential_evolution step 159: f(x)= 3.699268414598933
# differential_evolution step 160: f(x)= 3.699268414598933
# differential_evolution step 161: f(x)= 3.699268414598933
# differential_evolution step 162: f(x)= 3.699268414598933
# differential_evolution step 163: f(x)= 3.699268414598933
# differential_evolution step 164: f(x)= 3.699268414598933
# differential_evolution step 165: f(x)= 3.699268414598933
# differential_evolution step 166: f(x)= 3.699268414598933
# differential_evolution step 167: f(x)= 3.696183986961187
# differential_evolution step 168: f(x)= 3.696183986961187
# differential_evolution step 169: f(x)= 3.696183986961187
# differential_evolution step 170: f(x)= 3.696183986961187
# differential_evolution step 171: f(x)= 3.696183986961187
# differential_evolution step 172: f(x)= 3.696183986961187
# differential_evolution step 173: f(x)= 3.696183986961187
# differential_evolution step 174: f(x)= 3.6627970276463753
# differential_evolution step 175: f(x)= 3.6627970276463753
# differential_evolution step 176: f(x)= 3.6518321865396652
# differential_evolution step 177: f(x)= 3.6518321865396652
# differential_evolution step 178: f(x)= 3.6518321865396652
# differential_evolution step 179: f(x)= 3.6518321865396652
# differential_evolution step 180: f(x)= 3.6512933938317174
# differential_evolution step 181: f(x)= 3.6512933938317174
# differential_evolution step 182: f(x)= 3.6367050562886405
# differential_evolution step 183: f(x)= 3.6304627601461386
# differential_evolution step 184: f(x)= 3.6304627601461386
# differential_evolution step 185: f(x)= 3.6304627601461386
# differential_evolution step 186: f(x)= 3.6304627601461386
# differential_evolution step 187: f(x)= 3.6304627601461386
# differential_evolution step 188: f(x)= 3.6304627601461386
# differential_evolution step 189: f(x)= 3.6304627601461386
# differential_evolution step 190: f(x)= 3.6304627601461386
# differential_evolution step 191: f(x)= 3.6304627601461386
# differential_evolution step 192: f(x)= 3.6304627601461386
# differential_evolution step 193: f(x)= 3.6303954891136403
# differential_evolution step 194: f(x)= 3.6303954891136403
# differential_evolution step 195: f(x)= 3.6247987001236717
# differential_evolution step 196: f(x)= 3.6247987001236717
# differential_evolution step 197: f(x)= 3.6247987001236717
# differential_evolution step 198: f(x)= 3.6247987001236717
# differential_evolution step 199: f(x)= 3.6247987001236717
# differential_evolution step 200: f(x)= 3.6247987001236717
# differential_evolution step 201: f(x)= 3.6226397290688443
# differential_evolution step 202: f(x)= 3.6226397290688443
# differential_evolution step 203: f(x)= 3.6226397290688443
# differential_evolution step 204: f(x)= 3.6226397290688443
# differential_evolution step 205: f(x)= 3.6226397290688443
# differential_evolution step 206: f(x)= 3.6106513642788163
# differential_evolution step 207: f(x)= 3.6106513642788163
# differential_evolution step 208: f(x)= 3.6106513642788163
# differential_evolution step 209: f(x)= 3.6106513642788163
# differential_evolution step 210: f(x)= 3.6106513642788163
# differential_evolution step 211: f(x)= 3.6106513642788163
# differential_evolution step 212: f(x)= 3.6106513642788163
# differential_evolution step 213: f(x)= 3.6106513642788163
# differential_evolution step 214: f(x)= 3.6106513642788163
# differential_evolution step 215: f(x)= 3.6106513642788163
# differential_evolution step 216: f(x)= 3.6106513642788163
# differential_evolution step 217: f(x)= 3.6106513642788163
# differential_evolution step 218: f(x)= 3.6034286017637513
# differential_evolution step 219: f(x)= 3.6034286017637513
# differential_evolution step 220: f(x)= 3.6034286017637513
# differential_evolution step 221: f(x)= 3.6034286017637513
# differential_evolution step 222: f(x)= 3.6034286017637513
# differential_evolution step 223: f(x)= 3.6034286017637513
# differential_evolution step 224: f(x)= 3.6034286017637513
# differential_evolution step 225: f(x)= 3.6034286017637513
# differential_evolution step 226: f(x)= 3.6034286017637513
# differential_evolution step 227: f(x)= 3.6034286017637513
# differential_evolution step 228: f(x)= 3.5975302079312463
# differential_evolution step 229: f(x)= 3.5975302079312463
# differential_evolution step 230: f(x)= 3.5975302079312463
# differential_evolution step 231: f(x)= 3.5975302079312463
# differential_evolution step 232: f(x)= 3.5975302079312463
# differential_evolution step 233: f(x)= 3.5975302079312463
# differential_evolution step 234: f(x)= 3.5975302079312463
# differential_evolution step 235: f(x)= 3.5975302079312463
# differential_evolution step 236: f(x)= 3.5975302079312463
# differential_evolution step 237: f(x)= 3.5975302079312463
# differential_evolution step 238: f(x)= 3.5975302079312463
# differential_evolution step 239: f(x)= 3.5957604912662555
# differential_evolution step 240: f(x)= 3.593070114870894
# differential_evolution step 241: f(x)= 3.593070114870894
# differential_evolution step 242: f(x)= 3.593070114870894
# differential_evolution step 243: f(x)= 3.593070114870894
# differential_evolution step 244: f(x)= 3.593070114870894
# differential_evolution step 245: f(x)= 3.593070114870894
# differential_evolution step 246: f(x)= 3.593070114870894
# differential_evolution step 247: f(x)= 3.593070114870894
# differential_evolution step 248: f(x)= 3.593070114870894
# differential_evolution step 249: f(x)= 3.593070114870894
# differential_evolution step 250: f(x)= 3.5927960738071496
# differential_evolution step 251: f(x)= 3.5927960738071496
# differential_evolution step 252: f(x)= 3.5927960738071496
# differential_evolution step 253: f(x)= 3.5927960738071496
# differential_evolution step 254: f(x)= 3.589772737892185
# differential_evolution step 255: f(x)= 3.5883956553691374
# differential_evolution step 256: f(x)= 3.5883956553691374
# differential_evolution step 257: f(x)= 3.5883956553691374
# differential_evolution step 258: f(x)= 3.5883956553691374
# differential_evolution step 259: f(x)= 3.5883956553691374
# differential_evolution step 260: f(x)= 3.5883956553691374
# differential_evolution step 261: f(x)= 3.5883956553691374
# differential_evolution step 262: f(x)= 3.5883956553691374
# differential_evolution step 263: f(x)= 3.5883956553691374
# differential_evolution step 264: f(x)= 3.5883956553691374
# differential_evolution step 265: f(x)= 3.5883956553691374
# differential_evolution step 266: f(x)= 3.5883956553691374
# differential_evolution step 267: f(x)= 3.5883956553691374
# differential_evolution step 268: f(x)= 3.5883956553691374
# differential_evolution step 269: f(x)= 3.5883956553691374
# differential_evolution step 270: f(x)= 3.5867355497975106
# differential_evolution step 271: f(x)= 3.5867355497975106
# differential_evolution step 272: f(x)= 3.5867355497975106
# differential_evolution step 273: f(x)= 3.5867355497975106
# differential_evolution step 274: f(x)= 3.5867355497975106
# differential_evolution step 275: f(x)= 3.58174578467036
# differential_evolution step 276: f(x)= 3.58174578467036
# differential_evolution step 277: f(x)= 3.58174578467036
# differential_evolution step 278: f(x)= 3.58174578467036
# differential_evolution step 279: f(x)= 3.58174578467036
# differential_evolution step 280: f(x)= 3.580904151799041
# differential_evolution step 281: f(x)= 3.580904151799041
# differential_evolution step 282: f(x)= 3.580904151799041
# differential_evolution step 283: f(x)= 3.580904151799041
# differential_evolution step 284: f(x)= 3.580904151799041
# differential_evolution step 285: f(x)= 3.580904151799041
# differential_evolution step 286: f(x)= 3.580904151799041
# differential_evolution step 287: f(x)= 3.5800158551145
# differential_evolution step 288: f(x)= 3.5800158551145
# differential_evolution step 289: f(x)= 3.5800158551145
# differential_evolution step 290: f(x)= 3.5800158551145
# differential_evolution step 291: f(x)= 3.5800158551145
# differential_evolution step 292: f(x)= 3.5800158551145
# differential_evolution step 293: f(x)= 3.5800158551145
# differential_evolution step 294: f(x)= 3.5800158551145
# differential_evolution step 295: f(x)= 3.5800158551145
# differential_evolution step 296: f(x)= 3.5800158551145
# differential_evolution step 297: f(x)= 3.5800158551145
# differential_evolution step 298: f(x)= 3.5800158551145
# differential_evolution step 299: f(x)= 3.5800158551145
# differential_evolution step 300: f(x)= 3.579417184875118
# differential_evolution step 301: f(x)= 3.579417184875118
# differential_evolution step 302: f(x)= 3.579417184875118
# differential_evolution step 303: f(x)= 3.579417184875118
# differential_evolution step 304: f(x)= 3.579417184875118
# differential_evolution step 305: f(x)= 3.579417184875118
# differential_evolution step 306: f(x)= 3.579417184875118
# differential_evolution step 307: f(x)= 3.5762928625753965
# differential_evolution step 308: f(x)= 3.574224301490118
# differential_evolution step 309: f(x)= 3.574224301490118
# differential_evolution step 310: f(x)= 3.572726675918227
# differential_evolution step 311: f(x)= 3.571456347174924
# differential_evolution step 312: f(x)= 3.571383939634262
# differential_evolution step 313: f(x)= 3.571383939634262
# differential_evolution step 314: f(x)= 3.571383939634262
# differential_evolution step 315: f(x)= 3.571383939634262
# differential_evolution step 316: f(x)= 3.570044244319762
# differential_evolution step 317: f(x)= 3.570044244319762
# differential_evolution step 318: f(x)= 3.570044244319762
# differential_evolution step 319: f(x)= 3.570044244319762
# differential_evolution step 320: f(x)= 3.570044244319762
# differential_evolution step 321: f(x)= 3.570044244319762
# differential_evolution step 322: f(x)= 3.570044244319762
# differential_evolution step 323: f(x)= 3.570044244319762
# differential_evolution step 324: f(x)= 3.5699720091315257
# differential_evolution step 325: f(x)= 3.5699720091315257
# differential_evolution step 326: f(x)= 3.567632582719299
# differential_evolution step 327: f(x)= 3.567632582719299
# differential_evolution step 328: f(x)= 3.567632582719299
# differential_evolution step 329: f(x)= 3.567632582719299
# differential_evolution step 330: f(x)= 3.567632582719299
# differential_evolution step 331: f(x)= 3.567632582719299
# differential_evolution step 332: f(x)= 3.567632582719299
# differential_evolution step 333: f(x)= 3.567632582719299
# differential_evolution step 334: f(x)= 3.567632582719299
# differential_evolution step 335: f(x)= 3.567632582719299
# differential_evolution step 336: f(x)= 3.567632582719299
# differential_evolution step 337: f(x)= 3.567632582719299
# differential_evolution step 338: f(x)= 3.567632582719299
# differential_evolution step 339: f(x)= 3.5672859805928034
# differential_evolution step 340: f(x)= 3.5672859805928034
# differential_evolution step 341: f(x)= 3.565737854917605
# differential_evolution step 342: f(x)= 3.565737854917605
# differential_evolution step 343: f(x)= 3.565737854917605
# differential_evolution step 344: f(x)= 3.565737854917605
# differential_evolution step 345: f(x)= 3.565737854917605
# differential_evolution step 346: f(x)= 3.5645872808926846
# differential_evolution step 347: f(x)= 3.5645872808926846
# differential_evolution step 348: f(x)= 3.5645872808926846
# differential_evolution step 349: f(x)= 3.5645872808926846
# differential_evolution step 350: f(x)= 3.5613363698276754
# differential_evolution step 351: f(x)= 3.5613363698276754
# differential_evolution step 352: f(x)= 3.5613363698276754
# differential_evolution step 353: f(x)= 3.5613363698276754
# differential_evolution step 354: f(x)= 3.559444902391775
# differential_evolution step 355: f(x)= 3.559444902391775
# differential_evolution step 356: f(x)= 3.559444902391775
# differential_evolution step 357: f(x)= 3.559444902391775
# differential_evolution step 358: f(x)= 3.558387762506187
# differential_evolution step 359: f(x)= 3.558387762506187
# differential_evolution step 360: f(x)= 3.558387762506187
# differential_evolution step 361: f(x)= 3.558387762506187
# differential_evolution step 362: f(x)= 3.558387762506187
# differential_evolution step 363: f(x)= 3.558387762506187
# differential_evolution step 364: f(x)= 3.558387762506187
# differential_evolution step 365: f(x)= 3.558387762506187
# differential_evolution step 366: f(x)= 3.558387762506187
# differential_evolution step 367: f(x)= 3.558387762506187
# differential_evolution step 368: f(x)= 3.557459497749213
# differential_evolution step 369: f(x)= 3.557459497749213
# differential_evolution step 370: f(x)= 3.5559788755517636
# differential_evolution step 371: f(x)= 3.5559788755517636
# differential_evolution step 372: f(x)= 3.5559788755517636
# differential_evolution step 373: f(x)= 3.5559788755517636
# differential_evolution step 374: f(x)= 3.5559788755517636
# differential_evolution step 375: f(x)= 3.5559788755517636
# differential_evolution step 376: f(x)= 3.5559788755517636
# differential_evolution step 377: f(x)= 3.554520175907159
# differential_evolution step 378: f(x)= 3.554520175907159
# differential_evolution step 379: f(x)= 3.554520175907159
# differential_evolution step 380: f(x)= 3.554520175907159
# differential_evolution step 381: f(x)= 3.554520175907159
# differential_evolution step 382: f(x)= 3.554520175907159
# differential_evolution step 383: f(x)= 3.554520175907159
# differential_evolution step 384: f(x)= 3.5534494217323047
# differential_evolution step 385: f(x)= 3.5534494217323047
# differential_evolution step 386: f(x)= 3.5534494217323047
# differential_evolution step 387: f(x)= 3.5534494217323047
# differential_evolution step 388: f(x)= 3.5534494217323047
# differential_evolution step 389: f(x)= 3.5534494217323047
# differential_evolution step 390: f(x)= 3.552803328757695
# differential_evolution step 391: f(x)= 3.552803328757695
# differential_evolution step 392: f(x)= 3.5520251488169574
# differential_evolution step 393: f(x)= 3.5520251488169574
# differential_evolution step 394: f(x)= 3.5520251488169574
# differential_evolution step 395: f(x)= 3.5520251488169574
# differential_evolution step 396: f(x)= 3.5520251488169574
# differential_evolution step 397: f(x)= 3.551870640085399
# differential_evolution step 398: f(x)= 3.547366026106873
# differential_evolution step 399: f(x)= 3.547366026106873
# differential_evolution step 400: f(x)= 3.547366026106873
# differential_evolution step 401: f(x)= 3.5464529428528233
# differential_evolution step 402: f(x)= 3.5464529428528233
# differential_evolution step 403: f(x)= 3.5464529428528233
# differential_evolution step 404: f(x)= 3.5464529428528233
# differential_evolution step 405: f(x)= 3.5464529428528233
# differential_evolution step 406: f(x)= 3.5464529428528233
# differential_evolution step 407: f(x)= 3.5447398411857187
# differential_evolution step 408: f(x)= 3.5447398411857187
# differential_evolution step 409: f(x)= 3.5447398411857187
# differential_evolution step 410: f(x)= 3.5447398411857187
# differential_evolution step 411: f(x)= 3.5447398411857187
# differential_evolution step 412: f(x)= 3.5447398411857187
# differential_evolution step 413: f(x)= 3.5447398411857187
# differential_evolution step 414: f(x)= 3.5447398411857187
# differential_evolution step 415: f(x)= 3.5447398411857187
# differential_evolution step 416: f(x)= 3.543564624338656
# differential_evolution step 417: f(x)= 3.543564624338656
# differential_evolution step 418: f(x)= 3.543564624338656
# differential_evolution step 419: f(x)= 3.543564624338656
# differential_evolution step 420: f(x)= 3.543564624338656
# differential_evolution step 421: f(x)= 3.543564624338656
# differential_evolution step 422: f(x)= 3.543564624338656
# differential_evolution step 423: f(x)= 3.543564624338656
# differential_evolution step 424: f(x)= 3.543564624338656
# differential_evolution step 425: f(x)= 3.543564624338656
# differential_evolution step 426: f(x)= 3.5430384808066915
# differential_evolution step 427: f(x)= 3.540125521004012
# differential_evolution step 428: f(x)= 3.540125521004012
# differential_evolution step 429: f(x)= 3.540125521004012
# differential_evolution step 430: f(x)= 3.540125521004012
# differential_evolution step 431: f(x)= 3.5387417448644385
# differential_evolution step 432: f(x)= 3.5387417448644385
# differential_evolution step 433: f(x)= 3.5387417448644385
# differential_evolution step 434: f(x)= 3.5387417448644385
# differential_evolution step 435: f(x)= 3.536696959709149
# differential_evolution step 436: f(x)= 3.536696959709149
# differential_evolution step 437: f(x)= 3.5361540800427287
# differential_evolution step 438: f(x)= 3.5361540800427287
# differential_evolution step 439: f(x)= 3.5357187544776334
# differential_evolution step 440: f(x)= 3.5357187544776334
# differential_evolution step 441: f(x)= 3.5357187544776334
# differential_evolution step 442: f(x)= 3.5357187544776334
# differential_evolution step 443: f(x)= 3.5356751227536347
# differential_evolution step 444: f(x)= 3.535546105090061
# differential_evolution step 445: f(x)= 3.535546105090061
# differential_evolution step 446: f(x)= 3.535546105090061
# differential_evolution step 447: f(x)= 3.535546105090061
# differential_evolution step 448: f(x)= 3.535546105090061
# differential_evolution step 449: f(x)= 3.535546105090061
# differential_evolution step 450: f(x)= 3.533594614540193
# differential_evolution step 451: f(x)= 3.533594614540193
# differential_evolution step 452: f(x)= 3.533594614540193
# differential_evolution step 453: f(x)= 3.533594614540193
# differential_evolution step 454: f(x)= 3.530861727252418
# differential_evolution step 455: f(x)= 3.530861727252418
# differential_evolution step 456: f(x)= 3.530861727252418
# differential_evolution step 457: f(x)= 3.530861727252418
# differential_evolution step 458: f(x)= 3.530861727252418
# differential_evolution step 459: f(x)= 3.530861727252418
# differential_evolution step 460: f(x)= 3.530861727252418
# differential_evolution step 461: f(x)= 3.530861727252418
# differential_evolution step 462: f(x)= 3.530861727252418
# differential_evolution step 463: f(x)= 3.530861727252418
# differential_evolution step 464: f(x)= 3.530861727252418
# differential_evolution step 465: f(x)= 3.530861727252418
# differential_evolution step 466: f(x)= 3.530861727252418
# differential_evolution step 467: f(x)= 3.530861727252418
# differential_evolution step 468: f(x)= 3.530861727252418
# differential_evolution step 469: f(x)= 3.530861727252418
# differential_evolution step 470: f(x)= 3.530861727252418
# differential_evolution step 471: f(x)= 3.530861727252418
# differential_evolution step 472: f(x)= 3.530861727252418
# differential_evolution step 473: f(x)= 3.530861727252418
# differential_evolution step 474: f(x)= 3.530861727252418
# differential_evolution step 475: f(x)= 3.530861727252418
# differential_evolution step 476: f(x)= 3.530861727252418
# differential_evolution step 477: f(x)= 3.529875218297636
# differential_evolution step 478: f(x)= 3.529875218297636
# differential_evolution step 479: f(x)= 3.529875218297636
# differential_evolution step 480: f(x)= 3.5298416430989525
# differential_evolution step 481: f(x)= 3.5298416430989525
# differential_evolution step 482: f(x)= 3.5298416430989525
# differential_evolution step 483: f(x)= 3.5298416430989525
# differential_evolution step 484: f(x)= 3.5298416430989525
# differential_evolution step 485: f(x)= 3.5298416430989525
# differential_evolution step 486: f(x)= 3.526947845632977
# differential_evolution step 487: f(x)= 3.526947845632977
# differential_evolution step 488: f(x)= 3.526947845632977
# differential_evolution step 489: f(x)= 3.526947845632977
# differential_evolution step 490: f(x)= 3.526947845632977
# differential_evolution step 491: f(x)= 3.526947845632977
# differential_evolution step 492: f(x)= 3.526947845632977
# differential_evolution step 493: f(x)= 3.526947845632977
# differential_evolution step 494: f(x)= 3.526947845632977
# differential_evolution step 495: f(x)= 3.526947845632977
# differential_evolution step 496: f(x)= 3.526947845632977
# differential_evolution step 497: f(x)= 3.526947845632977
# differential_evolution step 498: f(x)= 3.526947845632977
# differential_evolution step 499: f(x)= 3.526947845632977
# differential_evolution step 500: f(x)= 3.526947845632977
# differential_evolution step 501: f(x)= 3.526947845632977
# differential_evolution step 502: f(x)= 3.526947845632977
# differential_evolution step 503: f(x)= 3.526947845632977
# differential_evolution step 504: f(x)= 3.526947845632977
# differential_evolution step 505: f(x)= 3.526947845632977
# differential_evolution step 506: f(x)= 3.526947845632977
# differential_evolution step 507: f(x)= 3.526947845632977
# differential_evolution step 508: f(x)= 3.526947845632977
# differential_evolution step 509: f(x)= 3.526947845632977
# differential_evolution step 510: f(x)= 3.526947845632977
# differential_evolution step 511: f(x)= 3.526947845632977
# differential_evolution step 512: f(x)= 3.526947845632977
# differential_evolution step 513: f(x)= 3.526947845632977
# differential_evolution step 514: f(x)= 3.526947845632977
# differential_evolution step 515: f(x)= 3.526947845632977
# differential_evolution step 516: f(x)= 3.526947845632977
# differential_evolution step 517: f(x)= 3.526947845632977
# differential_evolution step 518: f(x)= 3.526947845632977
# differential_evolution step 519: f(x)= 3.526947845632977
# differential_evolution step 520: f(x)= 3.526947845632977
# differential_evolution step 521: f(x)= 3.526947845632977
# differential_evolution step 522: f(x)= 3.526947845632977
# differential_evolution step 523: f(x)= 3.526947845632977
# differential_evolution step 524: f(x)= 3.526500929680396
# differential_evolution step 525: f(x)= 3.526500929680396
# differential_evolution step 526: f(x)= 3.526500929680396
# differential_evolution step 527: f(x)= 3.526500929680396
# differential_evolution step 528: f(x)= 3.526500929680396
# differential_evolution step 529: f(x)= 3.526500929680396
# differential_evolution step 530: f(x)= 3.526500929680396
# differential_evolution step 531: f(x)= 3.526500929680396
# differential_evolution step 532: f(x)= 3.526500929680396
# differential_evolution step 533: f(x)= 3.526500929680396
# differential_evolution step 534: f(x)= 3.526500929680396
# differential_evolution step 535: f(x)= 3.526500929680396
# differential_evolution step 536: f(x)= 3.526500929680396
# differential_evolution step 537: f(x)= 3.526360524501225
# differential_evolution step 538: f(x)= 3.526360524501225
# differential_evolution step 539: f(x)= 3.526360524501225
# differential_evolution step 540: f(x)= 3.526360524501225
# differential_evolution step 541: f(x)= 3.526360524501225
# differential_evolution step 542: f(x)= 3.526360524501225
# differential_evolution step 543: f(x)= 3.526360524501225
# differential_evolution step 544: f(x)= 3.526360524501225
# differential_evolution step 545: f(x)= 3.526360524501225
# differential_evolution step 546: f(x)= 3.526360524501225
# differential_evolution step 547: f(x)= 3.526360524501225
# differential_evolution step 548: f(x)= 3.526360524501225
# differential_evolution step 549: f(x)= 3.526360524501225
# differential_evolution step 550: f(x)= 3.526360524501225
# differential_evolution step 551: f(x)= 3.526360524501225
# differential_evolution step 552: f(x)= 3.526360524501225
# differential_evolution step 553: f(x)= 3.526360524501225
# differential_evolution step 554: f(x)= 3.526360524501225
# differential_evolution step 555: f(x)= 3.526360524501225
# differential_evolution step 556: f(x)= 3.526360524501225
# differential_evolution step 557: f(x)= 3.526360524501225
# differential_evolution step 558: f(x)= 3.526360524501225
# differential_evolution step 559: f(x)= 3.526360524501225
# differential_evolution step 560: f(x)= 3.526360524501225
# differential_evolution step 561: f(x)= 3.526360524501225
# differential_evolution step 562: f(x)= 3.526360524501225
# differential_evolution step 563: f(x)= 3.526360524501225
# differential_evolution step 564: f(x)= 3.526360524501225
# differential_evolution step 565: f(x)= 3.5257805373815017
# differential_evolution step 566: f(x)= 3.5257805373815017
# differential_evolution step 567: f(x)= 3.5257805373815017
# differential_evolution step 568: f(x)= 3.5257805373815017
# differential_evolution step 569: f(x)= 3.5257805373815017
# differential_evolution step 570: f(x)= 3.5257805373815017
# differential_evolution step 571: f(x)= 3.5257805373815017
# differential_evolution step 572: f(x)= 3.5257805373815017
# differential_evolution step 573: f(x)= 3.5257805373815017
# differential_evolution step 574: f(x)= 3.5257805373815017
# differential_evolution step 575: f(x)= 3.5257805373815017
# differential_evolution step 576: f(x)= 3.5257805373815017
# differential_evolution step 577: f(x)= 3.5257805373815017
# differential_evolution step 578: f(x)= 3.5257805373815017
# differential_evolution step 579: f(x)= 3.5257805373815017
# differential_evolution step 580: f(x)= 3.5257805373815017
# differential_evolution step 581: f(x)= 3.5257805373815017
# differential_evolution step 582: f(x)= 3.5257805373815017
# differential_evolution step 583: f(x)= 3.5257805373815017
# differential_evolution step 584: f(x)= 3.5257805373815017
# differential_evolution step 585: f(x)= 3.5257805373815017
# differential_evolution step 586: f(x)= 3.5257805373815017
# differential_evolution step 587: f(x)= 3.5257805373815017
# differential_evolution step 588: f(x)= 3.5257805373815017
# differential_evolution step 589: f(x)= 3.5257805373815017
# differential_evolution step 590: f(x)= 3.5257805373815017
# differential_evolution step 591: f(x)= 3.5257805373815017
# differential_evolution step 592: f(x)= 3.5257805373815017
# differential_evolution step 593: f(x)= 3.5257406851879214
# differential_evolution step 594: f(x)= 3.5257406851879214
# differential_evolution step 595: f(x)= 3.5257406851879214
# differential_evolution step 596: f(x)= 3.5257406851879214
# differential_evolution step 597: f(x)= 3.5257406851879214
# differential_evolution step 598: f(x)= 3.525729303426983
# differential_evolution step 599: f(x)= 3.525729303426983
# differential_evolution step 600: f(x)= 3.525729303426983
# differential_evolution step 601: f(x)= 3.525729303426983
# differential_evolution step 602: f(x)= 3.5256567442223865
# differential_evolution step 603: f(x)= 3.5256567442223865
# differential_evolution step 604: f(x)= 3.5256567442223865
# differential_evolution step 605: f(x)= 3.5256567442223865
# differential_evolution step 606: f(x)= 3.5256567442223865
# differential_evolution step 607: f(x)= 3.5256567442223865
# differential_evolution step 608: f(x)= 3.525419959155201
# differential_evolution step 609: f(x)= 3.525419959155201
# differential_evolution step 610: f(x)= 3.525419959155201
# differential_evolution step 611: f(x)= 3.525419959155201
# differential_evolution step 612: f(x)= 3.525419959155201
# differential_evolution step 613: f(x)= 3.525419959155201
# differential_evolution step 614: f(x)= 3.525419959155201
# differential_evolution step 615: f(x)= 3.525419959155201
# differential_evolution step 616: f(x)= 3.525419959155201
# differential_evolution step 617: f(x)= 3.525419959155201
# differential_evolution step 618: f(x)= 3.525419959155201
# differential_evolution step 619: f(x)= 3.525419959155201
# differential_evolution step 620: f(x)= 3.525419959155201
# differential_evolution step 621: f(x)= 3.525419959155201
# differential_evolution step 622: f(x)= 3.525419959155201
# differential_evolution step 623: f(x)= 3.525419959155201
# differential_evolution step 624: f(x)= 3.525419959155201
# differential_evolution step 625: f(x)= 3.525419959155201
# differential_evolution step 626: f(x)= 3.525419959155201
# differential_evolution step 627: f(x)= 3.525419959155201
# differential_evolution step 628: f(x)= 3.525419959155201
# differential_evolution step 629: f(x)= 3.525419959155201
# differential_evolution step 630: f(x)= 3.525419959155201
# differential_evolution step 631: f(x)= 3.525419959155201
# differential_evolution step 632: f(x)= 3.525419959155201
# differential_evolution step 633: f(x)= 3.525419959155201
# differential_evolution step 634: f(x)= 3.525419959155201
# differential_evolution step 635: f(x)= 3.525419959155201
# differential_evolution step 636: f(x)= 3.525419959155201
# differential_evolution step 637: f(x)= 3.525419959155201
# differential_evolution step 638: f(x)= 3.525419959155201
# differential_evolution step 639: f(x)= 3.525419959155201
# differential_evolution step 640: f(x)= 3.525419959155201
# differential_evolution step 641: f(x)= 3.5253898316744934
# differential_evolution step 642: f(x)= 3.5253898316744934
# differential_evolution step 643: f(x)= 3.5253898316744934
# differential_evolution step 644: f(x)= 3.5253898316744934
# differential_evolution step 645: f(x)= 3.5253898316744934
# differential_evolution step 646: f(x)= 3.5253898316744934
# differential_evolution step 647: f(x)= 3.5253898316744934
# differential_evolution step 648: f(x)= 3.5253898316744934
# differential_evolution step 649: f(x)= 3.5253898316744934
# differential_evolution step 650: f(x)= 3.5253898316744934
# differential_evolution step 651: f(x)= 3.5252700101578407
# differential_evolution step 652: f(x)= 3.5252700101578407
# differential_evolution step 653: f(x)= 3.5251481850230553
# differential_evolution step 654: f(x)= 3.5251481850230553
# differential_evolution step 655: f(x)= 3.5251481850230553
# differential_evolution step 656: f(x)= 3.5251481850230553
# differential_evolution step 657: f(x)= 3.5251481850230553
# differential_evolution step 658: f(x)= 3.5251481850230553
# differential_evolution step 659: f(x)= 3.5251481850230553
# differential_evolution step 660: f(x)= 3.5251481850230553
# differential_evolution step 661: f(x)= 3.5251370490190275
# differential_evolution step 662: f(x)= 3.5251370490190275
# differential_evolution step 663: f(x)= 3.5250498880128287
# differential_evolution step 664: f(x)= 3.5250498880128287
# differential_evolution step 665: f(x)= 3.5250498880128287
# differential_evolution step 666: f(x)= 3.525043858266448
# differential_evolution step 667: f(x)= 3.525043858266448
# differential_evolution step 668: f(x)= 3.525043858266448
# differential_evolution step 669: f(x)= 3.525043858266448
# differential_evolution step 670: f(x)= 3.525043858266448
# differential_evolution step 671: f(x)= 3.525043858266448
# differential_evolution step 672: f(x)= 3.525043858266448
# differential_evolution step 673: f(x)= 3.525043858266448
# differential_evolution step 674: f(x)= 3.525043858266448
# differential_evolution step 675: f(x)= 3.525043858266448
# differential_evolution step 676: f(x)= 3.525043858266448
# differential_evolution step 677: f(x)= 3.525043858266448
# differential_evolution step 678: f(x)= 3.525043858266448
# differential_evolution step 679: f(x)= 3.525043858266448
# differential_evolution step 680: f(x)= 3.5250404124608745
# differential_evolution step 681: f(x)= 3.5250404124608745
# differential_evolution step 682: f(x)= 3.5250404124608745
# differential_evolution step 683: f(x)= 3.5250404124608745
# differential_evolution step 684: f(x)= 3.5250404124608745
# differential_evolution step 685: f(x)= 3.5250404124608745
# differential_evolution step 686: f(x)= 3.5250404124608745
# differential_evolution step 687: f(x)= 3.5250404124608745
# differential_evolution step 688: f(x)= 3.5250404124608745
# differential_evolution step 689: f(x)= 3.5250404124608745
# differential_evolution step 690: f(x)= 3.52503303789835
# differential_evolution step 691: f(x)= 3.52503303789835
# differential_evolution step 692: f(x)= 3.52503303789835
# differential_evolution step 693: f(x)= 3.52503303789835
# differential_evolution step 694: f(x)= 3.52503303789835
# differential_evolution step 695: f(x)= 3.52503303789835
# differential_evolution step 696: f(x)= 3.52503303789835
# differential_evolution step 697: f(x)= 3.52503303789835
# differential_evolution step 698: f(x)= 3.5250327852478924
# differential_evolution step 699: f(x)= 3.5250327852478924
# differential_evolution step 700: f(x)= 3.5250327852478924
# differential_evolution step 701: f(x)= 3.5250327852478924
# differential_evolution step 702: f(x)= 3.5250327852478924
# differential_evolution step 703: f(x)= 3.5250327852478924
# differential_evolution step 704: f(x)= 3.5250327852478924
# differential_evolution step 705: f(x)= 3.5249238310210886
# differential_evolution step 706: f(x)= 3.5249238310210886
# differential_evolution step 707: f(x)= 3.524835027361453
# differential_evolution step 708: f(x)= 3.524835027361453
# differential_evolution step 709: f(x)= 3.524835027361453
# differential_evolution step 710: f(x)= 3.524835027361453
# differential_evolution step 711: f(x)= 3.524835027361453
# differential_evolution step 712: f(x)= 3.524835027361453
# differential_evolution step 713: f(x)= 3.524835027361453
# differential_evolution step 714: f(x)= 3.524835027361453
# differential_evolution step 715: f(x)= 3.524835027361453
# differential_evolution step 716: f(x)= 3.524835027361453
# differential_evolution step 717: f(x)= 3.524835027361453
# differential_evolution step 718: f(x)= 3.524835027361453
# differential_evolution step 719: f(x)= 3.524835027361453
# differential_evolution step 720: f(x)= 3.524835027361453
# differential_evolution step 721: f(x)= 3.524835027361453
# differential_evolution step 722: f(x)= 3.524835027361453
# differential_evolution step 723: f(x)= 3.524835027361453
# differential_evolution step 724: f(x)= 3.524835027361453
# differential_evolution step 725: f(x)= 3.524692909669705
# differential_evolution step 726: f(x)= 3.524692909669705
# differential_evolution step 727: f(x)= 3.524692909669705
# differential_evolution step 728: f(x)= 3.524692909669705
# differential_evolution step 729: f(x)= 3.524692909669705
# differential_evolution step 730: f(x)= 3.524692909669705
# differential_evolution step 731: f(x)= 3.524692909669705
# differential_evolution step 732: f(x)= 3.524692909669705
# differential_evolution step 733: f(x)= 3.524692909669705
# differential_evolution step 734: f(x)= 3.524692909669705
# differential_evolution step 735: f(x)= 3.524692909669705
# differential_evolution step 736: f(x)= 3.524692909669705
# differential_evolution step 737: f(x)= 3.524692909669705
# differential_evolution step 738: f(x)= 3.524692909669705
# differential_evolution step 739: f(x)= 3.524692909669705
# differential_evolution step 740: f(x)= 3.524692909669705
# differential_evolution step 741: f(x)= 3.524692909669705
# differential_evolution step 742: f(x)= 3.524692909669705
# differential_evolution step 743: f(x)= 3.524692909669705
# differential_evolution step 744: f(x)= 3.524692909669705
# differential_evolution step 745: f(x)= 3.524692909669705
# differential_evolution step 746: f(x)= 3.524692909669705
# differential_evolution step 747: f(x)= 3.524692909669705
# differential_evolution step 748: f(x)= 3.524692909669705
# differential_evolution step 749: f(x)= 3.524692909669705
# differential_evolution step 750: f(x)= 3.524692909669705
# differential_evolution step 751: f(x)= 3.524692909669705
# differential_evolution step 752: f(x)= 3.524665210313007
# differential_evolution step 753: f(x)= 3.524665210313007
# differential_evolution step 754: f(x)= 3.524665210313007
# differential_evolution step 755: f(x)= 3.524665210313007
# differential_evolution step 756: f(x)= 3.524665210313007
# differential_evolution step 757: f(x)= 3.524665210313007
# differential_evolution step 758: f(x)= 3.524665210313007
# differential_evolution step 759: f(x)= 3.524665210313007
# differential_evolution step 760: f(x)= 3.524665210313007
# differential_evolution step 761: f(x)= 3.5246583935615745
# differential_evolution step 762: f(x)= 3.5246583935615745
# differential_evolution step 763: f(x)= 3.5246583935615745
# differential_evolution step 764: f(x)= 3.5246583935615745
# differential_evolution step 765: f(x)= 3.5246583935615745
# differential_evolution step 766: f(x)= 3.5246583935615745
# differential_evolution step 767: f(x)= 3.5246182840669813
# differential_evolution step 768: f(x)= 3.5246129937138004
# differential_evolution step 769: f(x)= 3.5246129937138004
# differential_evolution step 770: f(x)= 3.5246129937138004
# differential_evolution step 771: f(x)= 3.5246129937138004
# differential_evolution step 772: f(x)= 3.5246129937138004
# differential_evolution step 773: f(x)= 3.5246129937138004
# differential_evolution step 774: f(x)= 3.5246109690002654
# differential_evolution step 775: f(x)= 3.5246109690002654
# differential_evolution step 776: f(x)= 3.5246109690002654
# differential_evolution step 777: f(x)= 3.5245502709357845
# differential_evolution step 778: f(x)= 3.5245502709357845
# differential_evolution step 779: f(x)= 3.5245502709357845
# differential_evolution step 780: f(x)= 3.5245151827694974
# differential_evolution step 781: f(x)= 3.5245151827694974
# differential_evolution step 782: f(x)= 3.5245151827694974
# differential_evolution step 783: f(x)= 3.5245151827694974
# differential_evolution step 784: f(x)= 3.5244974708788055
# differential_evolution step 785: f(x)= 3.5244974708788055
# differential_evolution step 786: f(x)= 3.5244974708788055
# differential_evolution step 787: f(x)= 3.5244974708788055
# differential_evolution step 788: f(x)= 3.5244974708788055
# differential_evolution step 789: f(x)= 3.5244974708788055
# differential_evolution step 790: f(x)= 3.5244974708788055
# differential_evolution step 791: f(x)= 3.5244974708788055
# differential_evolution step 792: f(x)= 3.5244974708788055
# differential_evolution step 793: f(x)= 3.5244974708788055
# differential_evolution step 794: f(x)= 3.5244974708788055
# differential_evolution step 795: f(x)= 3.5244974708788055
# differential_evolution step 796: f(x)= 3.5244974708788055
# differential_evolution step 797: f(x)= 3.5244974708788055
# differential_evolution step 798: f(x)= 3.5244974708788055
# differential_evolution step 799: f(x)= 3.5244974708788055
# differential_evolution step 800: f(x)= 3.5244974708788055
# differential_evolution step 801: f(x)= 3.5244974708788055
# differential_evolution step 802: f(x)= 3.5244974708788055
# differential_evolution step 803: f(x)= 3.524448353079068
# differential_evolution step 804: f(x)= 3.524448353079068
# differential_evolution step 805: f(x)= 3.524448353079068
# differential_evolution step 806: f(x)= 3.524448353079068
# differential_evolution step 807: f(x)= 3.524448353079068
# differential_evolution step 808: f(x)= 3.524448353079068
# differential_evolution step 809: f(x)= 3.524448353079068
# differential_evolution step 810: f(x)= 3.524438180833
# differential_evolution step 811: f(x)= 3.524438180833
# differential_evolution step 812: f(x)= 3.524438180833
# differential_evolution step 813: f(x)= 3.524438180833
# differential_evolution step 814: f(x)= 3.524438180833
# differential_evolution step 815: f(x)= 3.524438180833
# differential_evolution step 816: f(x)= 3.524438180833
# differential_evolution step 817: f(x)= 3.524438180833
# differential_evolution step 818: f(x)= 3.524438180833
# differential_evolution step 819: f(x)= 3.524438180833
# differential_evolution step 820: f(x)= 3.524438180833
# differential_evolution step 821: f(x)= 3.524438180833
# differential_evolution step 822: f(x)= 3.524438180833
# differential_evolution step 823: f(x)= 3.52441747800965
# differential_evolution step 824: f(x)= 3.52441747800965
# differential_evolution step 825: f(x)= 3.52441747800965
# differential_evolution step 826: f(x)= 3.52441747800965
# differential_evolution step 827: f(x)= 3.52441747800965
# differential_evolution step 828: f(x)= 3.52441747800965
# differential_evolution step 829: f(x)= 3.52441747800965
# differential_evolution step 830: f(x)= 3.5244096565520806
# differential_evolution step 831: f(x)= 3.5244096565520806
# differential_evolution step 832: f(x)= 3.5244096565520806
# differential_evolution step 833: f(x)= 3.5244096565520806
# differential_evolution step 834: f(x)= 3.5244096565520806
# differential_evolution step 835: f(x)= 3.5244096565520806
# differential_evolution step 836: f(x)= 3.5243507841768604
# differential_evolution step 837: f(x)= 3.5243507841768604
# differential_evolution step 838: f(x)= 3.5243507841768604
# differential_evolution step 839: f(x)= 3.5243507841768604
# differential_evolution step 840: f(x)= 3.5243507841768604
# differential_evolution step 841: f(x)= 3.5243507841768604
# differential_evolution step 842: f(x)= 3.5243507841768604
# differential_evolution step 843: f(x)= 3.5243507841768604
# differential_evolution step 844: f(x)= 3.5243507841768604
# differential_evolution step 845: f(x)= 3.5243507841768604
# differential_evolution step 846: f(x)= 3.5243507841768604
# differential_evolution step 847: f(x)= 3.5243507841768604
# differential_evolution step 848: f(x)= 3.5243507841768604
# differential_evolution step 849: f(x)= 3.5243507841768604
# differential_evolution step 850: f(x)= 3.5243507841768604
# differential_evolution step 851: f(x)= 3.5243507841768604
# differential_evolution step 852: f(x)= 3.5243507841768604
# differential_evolution step 853: f(x)= 3.5243507841768604
# differential_evolution step 854: f(x)= 3.5243507841768604
# differential_evolution step 855: f(x)= 3.5243507841768604
# differential_evolution step 856: f(x)= 3.5243507841768604
# differential_evolution step 857: f(x)= 3.5243504894453106
# differential_evolution step 858: f(x)= 3.5243504894453106
# differential_evolution step 859: f(x)= 3.5243504894453106
# differential_evolution step 860: f(x)= 3.5243504894453106
# differential_evolution step 861: f(x)= 3.5243504894453106
# differential_evolution step 862: f(x)= 3.5243504894453106
# differential_evolution step 863: f(x)= 3.5243504894453106
# differential_evolution step 864: f(x)= 3.5243504894453106
# differential_evolution step 865: f(x)= 3.5243225104599434
# differential_evolution step 866: f(x)= 3.5243225104599434
# differential_evolution step 867: f(x)= 3.5243225104599434
# differential_evolution step 868: f(x)= 3.5243225104599434
# differential_evolution step 869: f(x)= 3.5243225104599434
# differential_evolution step 870: f(x)= 3.5243225104599434
# differential_evolution step 871: f(x)= 3.5243225104599434
# differential_evolution step 872: f(x)= 3.5243225104599434
# differential_evolution step 873: f(x)= 3.5243225104599434
# differential_evolution step 874: f(x)= 3.5243225104599434
# differential_evolution step 875: f(x)= 3.5243225104599434
# differential_evolution step 876: f(x)= 3.5243225104599434
# differential_evolution step 877: f(x)= 3.5243225104599434
# differential_evolution step 878: f(x)= 3.5243225104599434
# differential_evolution step 879: f(x)= 3.5243225104599434
# differential_evolution step 880: f(x)= 3.5243225104599434
# differential_evolution step 881: f(x)= 3.5243225104599434
# differential_evolution step 882: f(x)= 3.5243225104599434
# differential_evolution step 883: f(x)= 3.5243225104599434
# differential_evolution step 884: f(x)= 3.5243225104599434
# differential_evolution step 885: f(x)= 3.5243225104599434
# differential_evolution step 886: f(x)= 3.5243225104599434
# differential_evolution step 887: f(x)= 3.5243225104599434
# differential_evolution step 888: f(x)= 3.5243225104599434
# differential_evolution step 889: f(x)= 3.5243225104599434
# differential_evolution step 890: f(x)= 3.5243225104599434
# differential_evolution step 891: f(x)= 3.5243225104599434
# differential_evolution step 892: f(x)= 3.5243225104599434
# differential_evolution step 893: f(x)= 3.5243225104599434
# differential_evolution step 894: f(x)= 3.5243225104599434
# differential_evolution step 895: f(x)= 3.5243225104599434
# differential_evolution step 896: f(x)= 3.5243225104599434
# differential_evolution step 897: f(x)= 3.5243225104599434
# differential_evolution step 898: f(x)= 3.5243221775630778
# differential_evolution step 899: f(x)= 3.5243221775630778
# differential_evolution step 900: f(x)= 3.5243221775630778
# differential_evolution step 901: f(x)= 3.5243221775630778
# differential_evolution step 902: f(x)= 3.524317228657226
# differential_evolution step 903: f(x)= 3.524317228657226
# differential_evolution step 904: f(x)= 3.524317228657226
# differential_evolution step 905: f(x)= 3.5243129725466567
# differential_evolution step 906: f(x)= 3.5243129725466567
# differential_evolution step 907: f(x)= 3.5243129725466567
# differential_evolution step 908: f(x)= 3.5243129725466567
# differential_evolution step 909: f(x)= 3.5243115825049522
# differential_evolution step 910: f(x)= 3.5243115825049522
# differential_evolution step 911: f(x)= 3.5243115825049522
# differential_evolution step 912: f(x)= 3.5243115825049522
# differential_evolution step 913: f(x)= 3.5243115825049522
# differential_evolution step 914: f(x)= 3.5243115825049522
# differential_evolution step 915: f(x)= 3.5243115825049522
# differential_evolution step 916: f(x)= 3.5243115825049522
# differential_evolution step 917: f(x)= 3.5243115825049522
# differential_evolution step 918: f(x)= 3.5243115825049522
# differential_evolution step 919: f(x)= 3.524308583373161
# differential_evolution step 920: f(x)= 3.524308583373161
# differential_evolution step 921: f(x)= 3.524304706437539
# differential_evolution step 922: f(x)= 3.524304706437539
# differential_evolution step 923: f(x)= 3.5243044999331326
# differential_evolution step 924: f(x)= 3.5242920707271854
# differential_evolution step 925: f(x)= 3.5242920707271854
# differential_evolution step 926: f(x)= 3.5242920707271854
# differential_evolution step 927: f(x)= 3.5242920707271854
# differential_evolution step 928: f(x)= 3.5242920707271854
# differential_evolution step 929: f(x)= 3.5242920707271854
# differential_evolution step 930: f(x)= 3.5242920707271854
# differential_evolution step 931: f(x)= 3.5242920707271854
# differential_evolution step 932: f(x)= 3.5242920707271854
# differential_evolution step 933: f(x)= 3.5242920707271854
# differential_evolution step 934: f(x)= 3.5242920707271854
# differential_evolution step 935: f(x)= 3.5242920707271854
# differential_evolution step 936: f(x)= 3.5242920707271854
# differential_evolution step 937: f(x)= 3.5242920707271854
# differential_evolution step 938: f(x)= 3.5242920707271854
# differential_evolution step 939: f(x)= 3.5242920707271854
# differential_evolution step 940: f(x)= 3.5242920707271854
# differential_evolution step 941: f(x)= 3.524278130862955
# differential_evolution step 942: f(x)= 3.524278130862955
# differential_evolution step 943: f(x)= 3.524278130862955
# differential_evolution step 944: f(x)= 3.524278130862955
# differential_evolution step 945: f(x)= 3.524278130862955
# differential_evolution step 946: f(x)= 3.524278130862955
# differential_evolution step 947: f(x)= 3.524278130862955
# differential_evolution step 948: f(x)= 3.524278130862955
# differential_evolution step 949: f(x)= 3.524278130862955
# differential_evolution step 950: f(x)= 3.524278130862955
# differential_evolution step 951: f(x)= 3.524278130862955
# differential_evolution step 952: f(x)= 3.524278130862955
# differential_evolution step 953: f(x)= 3.524278130862955
# differential_evolution step 954: f(x)= 3.524278130862955
# differential_evolution step 955: f(x)= 3.524278130862955
# differential_evolution step 956: f(x)= 3.524278130862955
# differential_evolution step 957: f(x)= 3.524278130862955
# differential_evolution step 958: f(x)= 3.524278130862955
# differential_evolution step 959: f(x)= 3.524278130862955
# differential_evolution step 960: f(x)= 3.524278130862955
# differential_evolution step 961: f(x)= 3.524278130862955
# differential_evolution step 962: f(x)= 3.524278130862955
# differential_evolution step 963: f(x)= 3.524278130862955
# differential_evolution step 964: f(x)= 3.524278130862955
# differential_evolution step 965: f(x)= 3.524278130862955
# differential_evolution step 966: f(x)= 3.524278130862955
# differential_evolution step 967: f(x)= 3.524278130862955
# differential_evolution step 968: f(x)= 3.524278130862955
# differential_evolution step 969: f(x)= 3.524278130862955
# differential_evolution step 970: f(x)= 3.524278130862955
# differential_evolution step 971: f(x)= 3.524278130862955
# differential_evolution step 972: f(x)= 3.524278130862955
# differential_evolution step 973: f(x)= 3.524278130862955
# differential_evolution step 974: f(x)= 3.524278130862955
# differential_evolution step 975: f(x)= 3.524278130862955
# differential_evolution step 976: f(x)= 3.524278130862955
# differential_evolution step 977: f(x)= 3.524278130862955
# differential_evolution step 978: f(x)= 3.524278130862955
# differential_evolution step 979: f(x)= 3.524278130862955
# differential_evolution step 980: f(x)= 3.524278130862955
# differential_evolution step 981: f(x)= 3.524278130862955
# differential_evolution step 982: f(x)= 3.524278130862955
# differential_evolution step 983: f(x)= 3.524278130862955
# differential_evolution step 984: f(x)= 3.524278130862955
# differential_evolution step 985: f(x)= 3.524278130862955
# differential_evolution step 986: f(x)= 3.524278130862955
# differential_evolution step 987: f(x)= 3.524278130862955
# differential_evolution step 988: f(x)= 3.524278130862955
# differential_evolution step 989: f(x)= 3.524278130862955
# differential_evolution step 990: f(x)= 3.524278130862955
# differential_evolution step 991: f(x)= 3.524278130862955
# differential_evolution step 992: f(x)= 3.524278130862955
# differential_evolution step 993: f(x)= 3.524278130862955
# differential_evolution step 994: f(x)= 3.524278130862955
# differential_evolution step 995: f(x)= 3.524278130862955
# differential_evolution step 996: f(x)= 3.524278130862955
# differential_evolution step 997: f(x)= 3.524278130862955
# differential_evolution step 998: f(x)= 3.524278130862955
# differential_evolution step 999: f(x)= 3.524272675425229
# differential_evolution step 1000: f(x)= 3.524272675425229
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.69035307e+00 4.89541115e+00 1.56500340e+00 3.27364624e+01
#  1.00473211e-02 4.99981046e+01 3.65592196e+00 7.02573143e+01
#  2.30616554e-01 4.99999920e+01 3.70902187e-01 1.79999822e+01]
# Chi quadro minimo: 3.524272675425229

# %%
# Plots:
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, 
                                         sigma = radial_profile_error_HA, bounds= bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4010, r_e=13.3186, n=2.7175, x_0=32.8112
# Sérsic 2: I_e=0.0281, r_e=49.9935, n=2.5749, x_0=69.8705
# Sérsic 3: I_e=0.0058, r_e=40.8605, n=3.4298, x_0=16.6404
# [1.55303201e-01 3.54184989e+00 3.23292871e-01 5.21677705e-02
#  3.96704935e-02 5.00213400e+01 1.26379658e+00 5.97921336e-03
#  3.62071353e-02 1.99926519e+02 4.86954017e+00 4.07273511e-01]
# 82.08018193336856
# 108.99606978383585 82.08018193336856 139.53008284675312 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (68, 73),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (19.5, 21),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 46107.52679735241
# differential_evolution step 2: f(x)= 19770.728643371847
# differential_evolution step 3: f(x)= 19770.728643371847
# differential_evolution step 4: f(x)= 17412.429655991353
# differential_evolution step 5: f(x)= 14294.58095052565
# differential_evolution step 6: f(x)= 8153.419909772727
# differential_evolution step 7: f(x)= 8153.419909772727
# differential_evolution step 8: f(x)= 3321.526336860277
# differential_evolution step 9: f(x)= 3321.526336860277
# differential_evolution step 10: f(x)= 2008.415495676763
# differential_evolution step 11: f(x)= 2008.415495676763
# differential_evolution step 12: f(x)= 2008.415495676763
# differential_evolution step 13: f(x)= 1229.9111297787617
# differential_evolution step 14: f(x)= 1161.753082675105
# differential_evolution step 15: f(x)= 1155.8546050184164
# differential_evolution step 16: f(x)= 901.1013121203582
# differential_evolution step 17: f(x)= 702.7842207989617
# differential_evolution step 18: f(x)= 381.9449630099333
# differential_evolution step 19: f(x)= 381.9449630099333
# differential_evolution step 20: f(x)= 381.9449630099333
# differential_evolution step 21: f(x)= 381.9449630099333
# differential_evolution step 22: f(x)= 70.74708926765052
# differential_evolution step 23: f(x)= 70.74708926765052
# differential_evolution step 24: f(x)= 70.74708926765052
# differential_evolution step 25: f(x)= 70.74708926765052
# differential_evolution step 26: f(x)= 70.74708926765052
# differential_evolution step 27: f(x)= 70.74708926765052
# differential_evolution step 28: f(x)= 70.74708926765052
# differential_evolution step 29: f(x)= 55.334758537718955
# differential_evolution step 30: f(x)= 32.90534094171425
# differential_evolution step 31: f(x)= 32.90534094171425
# differential_evolution step 32: f(x)= 32.90534094171425
# differential_evolution step 33: f(x)= 32.90534094171425
# differential_evolution step 34: f(x)= 32.90534094171425
# differential_evolution step 35: f(x)= 32.90534094171425
# differential_evolution step 36: f(x)= 32.90534094171425
# differential_evolution step 37: f(x)= 32.90534094171425
# differential_evolution step 38: f(x)= 32.90534094171425
# differential_evolution step 39: f(x)= 32.90534094171425
# differential_evolution step 40: f(x)= 32.90534094171425
# differential_evolution step 41: f(x)= 32.90534094171425
# differential_evolution step 42: f(x)= 32.90534094171425
# differential_evolution step 43: f(x)= 32.90534094171425
# differential_evolution step 44: f(x)= 32.90534094171425
# differential_evolution step 45: f(x)= 29.731341581599395
# differential_evolution step 46: f(x)= 29.731341581599395
# differential_evolution step 47: f(x)= 16.65163831159351
# differential_evolution step 48: f(x)= 16.65163831159351
# differential_evolution step 49: f(x)= 16.01812298790713
# differential_evolution step 50: f(x)= 16.01812298790713
# differential_evolution step 51: f(x)= 15.749773606528404
# differential_evolution step 52: f(x)= 15.749773606528404
# differential_evolution step 53: f(x)= 15.749773606528404
# differential_evolution step 54: f(x)= 15.749773606528404
# differential_evolution step 55: f(x)= 15.749773606528404
# differential_evolution step 56: f(x)= 15.749773606528404
# differential_evolution step 57: f(x)= 10.661685373084623
# differential_evolution step 58: f(x)= 10.661685373084623
# differential_evolution step 59: f(x)= 10.661685373084623
# differential_evolution step 60: f(x)= 10.661685373084623
# differential_evolution step 61: f(x)= 10.44186251416695
# differential_evolution step 62: f(x)= 9.95508085022812
# differential_evolution step 63: f(x)= 9.95508085022812
# differential_evolution step 64: f(x)= 9.95508085022812
# differential_evolution step 65: f(x)= 9.95508085022812
# differential_evolution step 66: f(x)= 9.95508085022812
# differential_evolution step 67: f(x)= 9.95508085022812
# differential_evolution step 68: f(x)= 9.393898781352444
# differential_evolution step 69: f(x)= 9.393898781352444
# differential_evolution step 70: f(x)= 9.393898781352444
# differential_evolution step 71: f(x)= 9.393898781352444
# differential_evolution step 72: f(x)= 9.393898781352444
# differential_evolution step 73: f(x)= 9.393898781352444
# differential_evolution step 74: f(x)= 9.393898781352444
# differential_evolution step 75: f(x)= 9.393898781352444
# differential_evolution step 76: f(x)= 9.393898781352444
# differential_evolution step 77: f(x)= 9.393898781352444
# differential_evolution step 78: f(x)= 9.393898781352444
# differential_evolution step 79: f(x)= 9.393898781352444
# differential_evolution step 80: f(x)= 9.393898781352444
# differential_evolution step 81: f(x)= 9.393898781352444
# differential_evolution step 82: f(x)= 9.393898781352444
# differential_evolution step 83: f(x)= 8.238948944276565
# differential_evolution step 84: f(x)= 8.238948944276565
# differential_evolution step 85: f(x)= 8.238948944276565
# differential_evolution step 86: f(x)= 6.698421670802368
# differential_evolution step 87: f(x)= 6.698421670802368
# differential_evolution step 88: f(x)= 6.698421670802368
# differential_evolution step 89: f(x)= 6.698421670802368
# differential_evolution step 90: f(x)= 6.698421670802368
# differential_evolution step 91: f(x)= 5.824512107672254
# differential_evolution step 92: f(x)= 5.824512107672254
# differential_evolution step 93: f(x)= 5.824512107672254
# differential_evolution step 94: f(x)= 5.824512107672254
# differential_evolution step 95: f(x)= 5.824512107672254
# differential_evolution step 96: f(x)= 5.824512107672254
# differential_evolution step 97: f(x)= 5.824512107672254
# differential_evolution step 98: f(x)= 5.824512107672254
# differential_evolution step 99: f(x)= 5.824512107672254
# differential_evolution step 100: f(x)= 5.824512107672254
# differential_evolution step 101: f(x)= 5.824512107672254
# differential_evolution step 102: f(x)= 5.824512107672254
# differential_evolution step 103: f(x)= 4.737066228975243
# differential_evolution step 104: f(x)= 4.737066228975243
# differential_evolution step 105: f(x)= 4.737066228975243
# differential_evolution step 106: f(x)= 4.737066228975243
# differential_evolution step 107: f(x)= 4.737066228975243
# differential_evolution step 108: f(x)= 4.737066228975243
# differential_evolution step 109: f(x)= 4.737066228975243
# differential_evolution step 110: f(x)= 4.737066228975243
# differential_evolution step 111: f(x)= 4.737066228975243
# differential_evolution step 112: f(x)= 4.737066228975243
# differential_evolution step 113: f(x)= 4.737066228975243
# differential_evolution step 114: f(x)= 4.737066228975243
# differential_evolution step 115: f(x)= 3.894144733417318
# differential_evolution step 116: f(x)= 3.894144733417318
# differential_evolution step 117: f(x)= 3.894144733417318
# differential_evolution step 118: f(x)= 3.894144733417318
# differential_evolution step 119: f(x)= 3.894144733417318
# differential_evolution step 120: f(x)= 3.894144733417318
# differential_evolution step 121: f(x)= 3.894144733417318
# differential_evolution step 122: f(x)= 3.860508048121645
# differential_evolution step 123: f(x)= 3.860508048121645
# differential_evolution step 124: f(x)= 3.860508048121645
# differential_evolution step 125: f(x)= 3.860508048121645
# differential_evolution step 126: f(x)= 3.860508048121645
# differential_evolution step 127: f(x)= 3.5693790847530975
# differential_evolution step 128: f(x)= 3.5693790847530975
# differential_evolution step 129: f(x)= 3.5693790847530975
# differential_evolution step 130: f(x)= 3.5693790847530975
# differential_evolution step 131: f(x)= 3.5693790847530975
# differential_evolution step 132: f(x)= 3.5693790847530975
# differential_evolution step 133: f(x)= 3.5693790847530975
# differential_evolution step 134: f(x)= 3.5693790847530975
# differential_evolution step 135: f(x)= 3.5693790847530975
# differential_evolution step 136: f(x)= 3.5693790847530975
# differential_evolution step 137: f(x)= 3.5693790847530975
# differential_evolution step 138: f(x)= 3.5693790847530975
# differential_evolution step 139: f(x)= 3.5693790847530975
# differential_evolution step 140: f(x)= 3.5693790847530975
# differential_evolution step 141: f(x)= 3.5693790847530975
# differential_evolution step 142: f(x)= 3.5693790847530975
# differential_evolution step 143: f(x)= 3.504797847281573
# differential_evolution step 144: f(x)= 3.504797847281573
# differential_evolution step 145: f(x)= 3.4044874280906554
# differential_evolution step 146: f(x)= 3.4044874280906554
# differential_evolution step 147: f(x)= 3.4044874280906554
# differential_evolution step 148: f(x)= 3.4044874280906554
# differential_evolution step 149: f(x)= 3.4044874280906554
# differential_evolution step 150: f(x)= 3.4044874280906554
# differential_evolution step 151: f(x)= 3.4044874280906554
# differential_evolution step 152: f(x)= 3.3845809890162606
# differential_evolution step 153: f(x)= 3.3845809890162606
# differential_evolution step 154: f(x)= 3.3845809890162606
# differential_evolution step 155: f(x)= 3.3845809890162606
# differential_evolution step 156: f(x)= 3.3845809890162606
# differential_evolution step 157: f(x)= 3.3845809890162606
# differential_evolution step 158: f(x)= 3.3845809890162606
# differential_evolution step 159: f(x)= 3.3845809890162606
# differential_evolution step 160: f(x)= 3.279585916034275
# differential_evolution step 161: f(x)= 3.279585916034275
# differential_evolution step 162: f(x)= 3.279585916034275
# differential_evolution step 163: f(x)= 3.279585916034275
# differential_evolution step 164: f(x)= 3.279585916034275
# differential_evolution step 165: f(x)= 3.279585916034275
# differential_evolution step 166: f(x)= 3.279585916034275
# differential_evolution step 167: f(x)= 3.279585916034275
# differential_evolution step 168: f(x)= 3.279585916034275
# differential_evolution step 169: f(x)= 3.279585916034275
# differential_evolution step 170: f(x)= 3.279585916034275
# differential_evolution step 171: f(x)= 3.279585916034275
# differential_evolution step 172: f(x)= 3.279585916034275
# differential_evolution step 173: f(x)= 3.279585916034275
# differential_evolution step 174: f(x)= 3.279585916034275
# differential_evolution step 175: f(x)= 3.279585916034275
# differential_evolution step 176: f(x)= 3.279585916034275
# differential_evolution step 177: f(x)= 3.1134405461648114
# differential_evolution step 178: f(x)= 3.1134405461648114
# differential_evolution step 179: f(x)= 3.1134405461648114
# differential_evolution step 180: f(x)= 3.1134405461648114
# differential_evolution step 181: f(x)= 3.1134405461648114
# differential_evolution step 182: f(x)= 3.1134405461648114
# differential_evolution step 183: f(x)= 3.1134405461648114
# differential_evolution step 184: f(x)= 3.111994463581386
# differential_evolution step 185: f(x)= 3.111994463581386
# differential_evolution step 186: f(x)= 3.111994463581386
# differential_evolution step 187: f(x)= 3.111994463581386
# differential_evolution step 188: f(x)= 3.101045011500881
# differential_evolution step 189: f(x)= 3.101045011500881
# differential_evolution step 190: f(x)= 3.101045011500881
# differential_evolution step 191: f(x)= 3.101045011500881
# differential_evolution step 192: f(x)= 3.101045011500881
# differential_evolution step 193: f(x)= 3.044934061889381
# differential_evolution step 194: f(x)= 3.044934061889381
# differential_evolution step 195: f(x)= 3.044934061889381
# differential_evolution step 196: f(x)= 3.044934061889381
# differential_evolution step 197: f(x)= 3.044934061889381
# differential_evolution step 198: f(x)= 3.014337228109543
# differential_evolution step 199: f(x)= 3.014337228109543
# differential_evolution step 200: f(x)= 3.014337228109543
# differential_evolution step 201: f(x)= 3.0038328366703544
# differential_evolution step 202: f(x)= 2.98436539143772
# differential_evolution step 203: f(x)= 2.98436539143772
# differential_evolution step 204: f(x)= 2.98436539143772
# differential_evolution step 205: f(x)= 2.975607446046028
# differential_evolution step 206: f(x)= 2.975607446046028
# differential_evolution step 207: f(x)= 2.9105288273124224
# differential_evolution step 208: f(x)= 2.8925144602231105
# differential_evolution step 209: f(x)= 2.8925144602231105
# differential_evolution step 210: f(x)= 2.7536784640539445
# differential_evolution step 211: f(x)= 2.7536784640539445
# differential_evolution step 212: f(x)= 2.7536784640539445
# differential_evolution step 213: f(x)= 2.6258126052708635
# differential_evolution step 214: f(x)= 2.6258126052708635
# differential_evolution step 215: f(x)= 2.5965580529746903
# differential_evolution step 216: f(x)= 2.5965580529746903
# differential_evolution step 217: f(x)= 2.5965580529746903
# differential_evolution step 218: f(x)= 2.5965580529746903
# differential_evolution step 219: f(x)= 2.5965580529746903
# differential_evolution step 220: f(x)= 2.5965580529746903
# differential_evolution step 221: f(x)= 2.5480100380839756
# differential_evolution step 222: f(x)= 2.5480100380839756
# differential_evolution step 223: f(x)= 2.5480100380839756
# differential_evolution step 224: f(x)= 2.5480100380839756
# differential_evolution step 225: f(x)= 2.5480100380839756
# differential_evolution step 226: f(x)= 2.5480100380839756
# differential_evolution step 227: f(x)= 2.541788252859088
# differential_evolution step 228: f(x)= 2.541788252859088
# differential_evolution step 229: f(x)= 2.541788252859088
# differential_evolution step 230: f(x)= 2.3944210337206417
# differential_evolution step 231: f(x)= 2.3944210337206417
# differential_evolution step 232: f(x)= 2.3944210337206417
# differential_evolution step 233: f(x)= 2.3944210337206417
# differential_evolution step 234: f(x)= 2.3944210337206417
# differential_evolution step 235: f(x)= 2.3944210337206417
# differential_evolution step 236: f(x)= 2.3944210337206417
# differential_evolution step 237: f(x)= 2.3944210337206417
# differential_evolution step 238: f(x)= 2.3944210337206417
# differential_evolution step 239: f(x)= 2.3944210337206417
# differential_evolution step 240: f(x)= 2.3944210337206417
# differential_evolution step 241: f(x)= 2.3944210337206417
# differential_evolution step 242: f(x)= 2.3944210337206417
# differential_evolution step 243: f(x)= 2.3944210337206417
# differential_evolution step 244: f(x)= 2.3944210337206417
# differential_evolution step 245: f(x)= 2.3944210337206417
# differential_evolution step 246: f(x)= 2.3944210337206417
# differential_evolution step 247: f(x)= 2.3944210337206417
# differential_evolution step 248: f(x)= 2.3944210337206417
# differential_evolution step 249: f(x)= 2.3944210337206417
# differential_evolution step 250: f(x)= 2.3944210337206417
# differential_evolution step 251: f(x)= 2.3944210337206417
# differential_evolution step 252: f(x)= 2.3944210337206417
# differential_evolution step 253: f(x)= 2.3944210337206417
# differential_evolution step 254: f(x)= 2.3944210337206417
# differential_evolution step 255: f(x)= 2.3944210337206417
# differential_evolution step 256: f(x)= 2.386372384606682
# differential_evolution step 257: f(x)= 2.386372384606682
# differential_evolution step 258: f(x)= 2.362547451660164
# differential_evolution step 259: f(x)= 2.362547451660164
# differential_evolution step 260: f(x)= 2.362547451660164
# differential_evolution step 261: f(x)= 2.362547451660164
# differential_evolution step 262: f(x)= 2.362547451660164
# differential_evolution step 263: f(x)= 2.362547451660164
# differential_evolution step 264: f(x)= 2.3437640946646194
# differential_evolution step 265: f(x)= 2.3437640946646194
# differential_evolution step 266: f(x)= 2.3437640946646194
# differential_evolution step 267: f(x)= 2.3437640946646194
# differential_evolution step 268: f(x)= 2.340656096322898
# differential_evolution step 269: f(x)= 2.340656096322898
# differential_evolution step 270: f(x)= 2.3082053691011843
# differential_evolution step 271: f(x)= 2.2945900598072138
# differential_evolution step 272: f(x)= 2.2945900598072138
# differential_evolution step 273: f(x)= 2.2904567622958782
# differential_evolution step 274: f(x)= 2.2904567622958782
# differential_evolution step 275: f(x)= 2.2904567622958782
# differential_evolution step 276: f(x)= 2.2799890910441123
# differential_evolution step 277: f(x)= 2.2799890910441123
# differential_evolution step 278: f(x)= 2.2799890910441123
# differential_evolution step 279: f(x)= 2.2799890910441123
# differential_evolution step 280: f(x)= 2.2799890910441123
# differential_evolution step 281: f(x)= 2.2799890910441123
# differential_evolution step 282: f(x)= 2.2799890910441123
# differential_evolution step 283: f(x)= 2.2799890910441123
# differential_evolution step 284: f(x)= 2.2799890910441123
# differential_evolution step 285: f(x)= 2.2799890910441123
# differential_evolution step 286: f(x)= 2.2799890910441123
# differential_evolution step 287: f(x)= 2.274278537346818
# differential_evolution step 288: f(x)= 2.274278537346818
# differential_evolution step 289: f(x)= 2.274278537346818
# differential_evolution step 290: f(x)= 2.274278537346818
# differential_evolution step 291: f(x)= 2.274278537346818
# differential_evolution step 292: f(x)= 2.2662597308051984
# differential_evolution step 293: f(x)= 2.2662597308051984
# differential_evolution step 294: f(x)= 2.2646782404065418
# differential_evolution step 295: f(x)= 2.2646782404065418
# differential_evolution step 296: f(x)= 2.2646782404065418
# differential_evolution step 297: f(x)= 2.2587545923123553
# differential_evolution step 298: f(x)= 2.2587545923123553
# differential_evolution step 299: f(x)= 2.2587545923123553
# differential_evolution step 300: f(x)= 2.2587545923123553
# differential_evolution step 301: f(x)= 2.2587545923123553
# differential_evolution step 302: f(x)= 2.2587545923123553
# differential_evolution step 303: f(x)= 2.2587545923123553
# differential_evolution step 304: f(x)= 2.2587545923123553
# differential_evolution step 305: f(x)= 2.2587545923123553
# differential_evolution step 306: f(x)= 2.2499743625265864
# differential_evolution step 307: f(x)= 2.2294281686737083
# differential_evolution step 308: f(x)= 2.2294281686737083
# differential_evolution step 309: f(x)= 2.2294281686737083
# differential_evolution step 310: f(x)= 2.2294281686737083
# differential_evolution step 311: f(x)= 2.2294281686737083
# differential_evolution step 312: f(x)= 2.2294281686737083
# differential_evolution step 313: f(x)= 2.2294281686737083
# differential_evolution step 314: f(x)= 2.2294281686737083
# differential_evolution step 315: f(x)= 2.2294281686737083
# differential_evolution step 316: f(x)= 2.2294281686737083
# differential_evolution step 317: f(x)= 2.2294281686737083
# differential_evolution step 318: f(x)= 2.2294281686737083
# differential_evolution step 319: f(x)= 2.2294281686737083
# differential_evolution step 320: f(x)= 2.213634772834932
# differential_evolution step 321: f(x)= 2.203743314032769
# differential_evolution step 322: f(x)= 2.203743314032769
# differential_evolution step 323: f(x)= 2.203743314032769
# differential_evolution step 324: f(x)= 2.203743314032769
# differential_evolution step 325: f(x)= 2.203743314032769
# differential_evolution step 326: f(x)= 2.203743314032769
# differential_evolution step 327: f(x)= 2.203743314032769
# differential_evolution step 328: f(x)= 2.203669794932588
# differential_evolution step 329: f(x)= 2.203669794932588
# differential_evolution step 330: f(x)= 2.203669794932588
# differential_evolution step 331: f(x)= 2.203669794932588
# differential_evolution step 332: f(x)= 2.2030776182328644
# differential_evolution step 333: f(x)= 2.2030776182328644
# differential_evolution step 334: f(x)= 2.189916062454753
# differential_evolution step 335: f(x)= 2.189916062454753
# differential_evolution step 336: f(x)= 2.189916062454753
# differential_evolution step 337: f(x)= 2.189916062454753
# differential_evolution step 338: f(x)= 2.189916062454753
# differential_evolution step 339: f(x)= 2.189916062454753
# differential_evolution step 340: f(x)= 2.189916062454753
# differential_evolution step 341: f(x)= 2.189916062454753
# differential_evolution step 342: f(x)= 2.189916062454753
# differential_evolution step 343: f(x)= 2.189916062454753
# differential_evolution step 344: f(x)= 2.189916062454753
# differential_evolution step 345: f(x)= 2.189916062454753
# differential_evolution step 346: f(x)= 2.1886716149814367
# differential_evolution step 347: f(x)= 2.1886716149814367
# differential_evolution step 348: f(x)= 2.1886716149814367
# differential_evolution step 349: f(x)= 2.1886716149814367
# differential_evolution step 350: f(x)= 2.1886716149814367
# differential_evolution step 351: f(x)= 2.1886716149814367
# differential_evolution step 352: f(x)= 2.1886716149814367
# differential_evolution step 353: f(x)= 2.1886716149814367
# differential_evolution step 354: f(x)= 2.1886716149814367
# differential_evolution step 355: f(x)= 2.1886716149814367
# differential_evolution step 356: f(x)= 2.1886716149814367
# differential_evolution step 357: f(x)= 2.1886716149814367
# differential_evolution step 358: f(x)= 2.188476591079592
# differential_evolution step 359: f(x)= 2.1819501765697833
# differential_evolution step 360: f(x)= 2.1819501765697833
# differential_evolution step 361: f(x)= 2.180739144972475
# differential_evolution step 362: f(x)= 2.180739144972475
# differential_evolution step 363: f(x)= 2.180739144972475
# differential_evolution step 364: f(x)= 2.173693448792308
# differential_evolution step 365: f(x)= 2.173693448792308
# differential_evolution step 366: f(x)= 2.173693448792308
# differential_evolution step 367: f(x)= 2.173693448792308
# differential_evolution step 368: f(x)= 2.173693448792308
# differential_evolution step 369: f(x)= 2.173693448792308
# differential_evolution step 370: f(x)= 2.173693448792308
# differential_evolution step 371: f(x)= 2.173693448792308
# differential_evolution step 372: f(x)= 2.173693448792308
# differential_evolution step 373: f(x)= 2.173693448792308
# differential_evolution step 374: f(x)= 2.173693448792308
# differential_evolution step 375: f(x)= 2.173693448792308
# differential_evolution step 376: f(x)= 2.170463225350479
# differential_evolution step 377: f(x)= 2.1647090571352288
# differential_evolution step 378: f(x)= 2.160467627154289
# differential_evolution step 379: f(x)= 2.160467627154289
# differential_evolution step 380: f(x)= 2.160467627154289
# differential_evolution step 381: f(x)= 2.1588424595362516
# differential_evolution step 382: f(x)= 2.1588424595362516
# differential_evolution step 383: f(x)= 2.1588424595362516
# differential_evolution step 384: f(x)= 2.1588424595362516
# differential_evolution step 385: f(x)= 2.1588424595362516
# differential_evolution step 386: f(x)= 2.1588424595362516
# differential_evolution step 387: f(x)= 2.1588424595362516
# differential_evolution step 388: f(x)= 2.1588424595362516
# differential_evolution step 389: f(x)= 2.1588424595362516
# differential_evolution step 390: f(x)= 2.1588424595362516
# differential_evolution step 391: f(x)= 2.1588424595362516
# differential_evolution step 392: f(x)= 2.1588424595362516
# differential_evolution step 393: f(x)= 2.1588424595362516
# differential_evolution step 394: f(x)= 2.1588424595362516
# differential_evolution step 395: f(x)= 2.1588424595362516
# differential_evolution step 396: f(x)= 2.156374279900372
# differential_evolution step 397: f(x)= 2.156374279900372
# differential_evolution step 398: f(x)= 2.156374279900372
# differential_evolution step 399: f(x)= 2.156374279900372
# differential_evolution step 400: f(x)= 2.156374279900372
# differential_evolution step 401: f(x)= 2.156374279900372
# differential_evolution step 402: f(x)= 2.156374279900372
# differential_evolution step 403: f(x)= 2.156374279900372
# differential_evolution step 404: f(x)= 2.156374279900372
# differential_evolution step 405: f(x)= 2.156374279900372
# differential_evolution step 406: f(x)= 2.156374279900372
# differential_evolution step 407: f(x)= 2.156374279900372
# differential_evolution step 408: f(x)= 2.156374279900372
# differential_evolution step 409: f(x)= 2.156374279900372
# differential_evolution step 410: f(x)= 2.156374279900372
# differential_evolution step 411: f(x)= 2.156374279900372
# differential_evolution step 412: f(x)= 2.156374279900372
# differential_evolution step 413: f(x)= 2.156374279900372
# differential_evolution step 414: f(x)= 2.156374279900372
# differential_evolution step 415: f(x)= 2.156374279900372
# differential_evolution step 416: f(x)= 2.156374279900372
# differential_evolution step 417: f(x)= 2.156374279900372
# differential_evolution step 418: f(x)= 2.156374279900372
# differential_evolution step 419: f(x)= 2.156374279900372
# differential_evolution step 420: f(x)= 2.156374279900372
# differential_evolution step 421: f(x)= 2.156374279900372
# differential_evolution step 422: f(x)= 2.156374279900372
# differential_evolution step 423: f(x)= 2.156374279900372
# differential_evolution step 424: f(x)= 2.156374279900372
# differential_evolution step 425: f(x)= 2.156374279900372
# differential_evolution step 426: f(x)= 2.156374279900372
# differential_evolution step 427: f(x)= 2.154034638676565
# differential_evolution step 428: f(x)= 2.154034638676565
# differential_evolution step 429: f(x)= 2.154034638676565
# differential_evolution step 430: f(x)= 2.14839237178182
# differential_evolution step 431: f(x)= 2.14839237178182
# differential_evolution step 432: f(x)= 2.14839237178182
# differential_evolution step 433: f(x)= 2.14839237178182
# differential_evolution step 434: f(x)= 2.14839237178182
# differential_evolution step 435: f(x)= 2.14839237178182
# differential_evolution step 436: f(x)= 2.14839237178182
# differential_evolution step 437: f(x)= 2.14839237178182
# differential_evolution step 438: f(x)= 2.14839237178182
# differential_evolution step 439: f(x)= 2.14839237178182
# differential_evolution step 440: f(x)= 2.14839237178182
# differential_evolution step 441: f(x)= 2.146217110390734
# differential_evolution step 442: f(x)= 2.146217110390734
# differential_evolution step 443: f(x)= 2.146217110390734
# differential_evolution step 444: f(x)= 2.146217110390734
# differential_evolution step 445: f(x)= 2.146217110390734
# differential_evolution step 446: f(x)= 2.146217110390734
# differential_evolution step 447: f(x)= 2.146217110390734
# differential_evolution step 448: f(x)= 2.146217110390734
# differential_evolution step 449: f(x)= 2.146217110390734
# differential_evolution step 450: f(x)= 2.146217110390734
# differential_evolution step 451: f(x)= 2.146217110390734
# differential_evolution step 452: f(x)= 2.143476427208517
# differential_evolution step 453: f(x)= 2.143476427208517
# differential_evolution step 454: f(x)= 2.143476427208517
# differential_evolution step 455: f(x)= 2.143476427208517
# differential_evolution step 456: f(x)= 2.143476427208517
# differential_evolution step 457: f(x)= 2.14338152838134
# differential_evolution step 458: f(x)= 2.1403545303118543
# differential_evolution step 459: f(x)= 2.1403545303118543
# differential_evolution step 460: f(x)= 2.1403545303118543
# differential_evolution step 461: f(x)= 2.1403545303118543
# differential_evolution step 462: f(x)= 2.1403545303118543
# differential_evolution step 463: f(x)= 2.1403545303118543
# differential_evolution step 464: f(x)= 2.1403545303118543
# differential_evolution step 465: f(x)= 2.1403545303118543
# differential_evolution step 466: f(x)= 2.1403545303118543
# differential_evolution step 467: f(x)= 2.1403545303118543
# differential_evolution step 468: f(x)= 2.1403545303118543
# differential_evolution step 469: f(x)= 2.1403545303118543
# differential_evolution step 470: f(x)= 2.1403545303118543
# differential_evolution step 471: f(x)= 2.1403545303118543
# differential_evolution step 472: f(x)= 2.140120244319274
# differential_evolution step 473: f(x)= 2.1399686983680875
# differential_evolution step 474: f(x)= 2.1399686983680875
# differential_evolution step 475: f(x)= 2.1399686983680875
# differential_evolution step 476: f(x)= 2.1399686983680875
# differential_evolution step 477: f(x)= 2.1399686983680875
# differential_evolution step 478: f(x)= 2.1399686983680875
# differential_evolution step 479: f(x)= 2.1399686983680875
# differential_evolution step 480: f(x)= 2.1399686983680875
# differential_evolution step 481: f(x)= 2.1399686983680875
# differential_evolution step 482: f(x)= 2.1399686983680875
# differential_evolution step 483: f(x)= 2.1399686983680875
# differential_evolution step 484: f(x)= 2.139901565757844
# differential_evolution step 485: f(x)= 2.1395095984549983
# differential_evolution step 486: f(x)= 2.1395095984549983
# differential_evolution step 487: f(x)= 2.1395095984549983
# differential_evolution step 488: f(x)= 2.1395095984549983
# differential_evolution step 489: f(x)= 2.1395095984549983
# differential_evolution step 490: f(x)= 2.138995545627677
# differential_evolution step 491: f(x)= 2.138995545627677
# differential_evolution step 492: f(x)= 2.138995545627677
# differential_evolution step 493: f(x)= 2.1387302322417208
# differential_evolution step 494: f(x)= 2.1387302322417208
# differential_evolution step 495: f(x)= 2.1387302322417208
# differential_evolution step 496: f(x)= 2.1387302322417208
# differential_evolution step 497: f(x)= 2.1387302322417208
# differential_evolution step 498: f(x)= 2.1387302322417208
# differential_evolution step 499: f(x)= 2.1387302322417208
# differential_evolution step 500: f(x)= 2.1387302322417208
# differential_evolution step 501: f(x)= 2.1380937215966287
# differential_evolution step 502: f(x)= 2.1380937215966287
# differential_evolution step 503: f(x)= 2.1380937215966287
# differential_evolution step 504: f(x)= 2.1380937215966287
# differential_evolution step 505: f(x)= 2.1380937215966287
# differential_evolution step 506: f(x)= 2.1380937215966287
# differential_evolution step 507: f(x)= 2.1380937215966287
# differential_evolution step 508: f(x)= 2.1380937215966287
# differential_evolution step 509: f(x)= 2.1380937215966287
# differential_evolution step 510: f(x)= 2.1380937215966287
# differential_evolution step 511: f(x)= 2.1380937215966287
# differential_evolution step 512: f(x)= 2.1380937215966287
# differential_evolution step 513: f(x)= 2.1380937215966287
# differential_evolution step 514: f(x)= 2.1380937215966287
# differential_evolution step 515: f(x)= 2.1380937215966287
# differential_evolution step 516: f(x)= 2.1380937215966287
# differential_evolution step 517: f(x)= 2.1380937215966287
# differential_evolution step 518: f(x)= 2.1380937215966287
# differential_evolution step 519: f(x)= 2.1380937215966287
# differential_evolution step 520: f(x)= 2.1380937215966287
# differential_evolution step 521: f(x)= 2.1380937215966287
# differential_evolution step 522: f(x)= 2.137476937107895
# differential_evolution step 523: f(x)= 2.137476937107895
# differential_evolution step 524: f(x)= 2.1373550011990394
# differential_evolution step 525: f(x)= 2.1373550011990394
# differential_evolution step 526: f(x)= 2.1373550011990394
# differential_evolution step 527: f(x)= 2.1373550011990394
# differential_evolution step 528: f(x)= 2.1373550011990394
# differential_evolution step 529: f(x)= 2.1373550011990394
# differential_evolution step 530: f(x)= 2.1373550011990394
# differential_evolution step 531: f(x)= 2.1373550011990394
# differential_evolution step 532: f(x)= 2.1373550011990394
# differential_evolution step 533: f(x)= 2.1372962146745156
# differential_evolution step 534: f(x)= 2.136941688371796
# differential_evolution step 535: f(x)= 2.136941688371796
# differential_evolution step 536: f(x)= 2.136941688371796
# differential_evolution step 537: f(x)= 2.136941688371796
# differential_evolution step 538: f(x)= 2.136941688371796
# differential_evolution step 539: f(x)= 2.136941688371796
# differential_evolution step 540: f(x)= 2.136941688371796
# differential_evolution step 541: f(x)= 2.136906894740091
# differential_evolution step 542: f(x)= 2.136906894740091
# differential_evolution step 543: f(x)= 2.136906894740091
# differential_evolution step 544: f(x)= 2.136906894740091
# differential_evolution step 545: f(x)= 2.136906894740091
# differential_evolution step 546: f(x)= 2.136906894740091
# differential_evolution step 547: f(x)= 2.136906894740091
# differential_evolution step 548: f(x)= 2.136906894740091
# differential_evolution step 549: f(x)= 2.136906894740091
# differential_evolution step 550: f(x)= 2.136906894740091
# differential_evolution step 551: f(x)= 2.136906894740091
# differential_evolution step 552: f(x)= 2.136906894740091
# differential_evolution step 553: f(x)= 2.136906894740091
# differential_evolution step 554: f(x)= 2.136906894740091
# differential_evolution step 555: f(x)= 2.136906894740091
# differential_evolution step 556: f(x)= 2.136575416696136
# differential_evolution step 557: f(x)= 2.136575416696136
# differential_evolution step 558: f(x)= 2.136575416696136
# differential_evolution step 559: f(x)= 2.136219332913523
# differential_evolution step 560: f(x)= 2.136219332913523
# differential_evolution step 561: f(x)= 2.1360933166940175
# differential_evolution step 562: f(x)= 2.1360479584442005
# differential_evolution step 563: f(x)= 2.1360479584442005
# differential_evolution step 564: f(x)= 2.1360479584442005
# differential_evolution step 565: f(x)= 2.1360479584442005
# differential_evolution step 566: f(x)= 2.1360479584442005
# differential_evolution step 567: f(x)= 2.1360479584442005
# differential_evolution step 568: f(x)= 2.1360479584442005
# differential_evolution step 569: f(x)= 2.1360479584442005
# differential_evolution step 570: f(x)= 2.1360479584442005
# differential_evolution step 571: f(x)= 2.1360479584442005
# differential_evolution step 572: f(x)= 2.1360479584442005
# differential_evolution step 573: f(x)= 2.1360479584442005
# differential_evolution step 574: f(x)= 2.1360474466105304
# differential_evolution step 575: f(x)= 2.135885838709851
# differential_evolution step 576: f(x)= 2.135885838709851
# differential_evolution step 577: f(x)= 2.135885838709851
# differential_evolution step 578: f(x)= 2.135885838709851
# differential_evolution step 579: f(x)= 2.135885838709851
# differential_evolution step 580: f(x)= 2.135885838709851
# differential_evolution step 581: f(x)= 2.1357005511964813
# differential_evolution step 582: f(x)= 2.1357005511964813
# differential_evolution step 583: f(x)= 2.1357005511964813
# differential_evolution step 584: f(x)= 2.1357005511964813
# differential_evolution step 585: f(x)= 2.1357005511964813
# differential_evolution step 586: f(x)= 2.1357005511964813
# differential_evolution step 587: f(x)= 2.1357005511964813
# differential_evolution step 588: f(x)= 2.1357005511964813
# differential_evolution step 589: f(x)= 2.1357005511964813
# differential_evolution step 590: f(x)= 2.1357005511964813
# differential_evolution step 591: f(x)= 2.1357005511964813
# differential_evolution step 592: f(x)= 2.1357005511964813
# differential_evolution step 593: f(x)= 2.135546908761359
# differential_evolution step 594: f(x)= 2.135546908761359
# differential_evolution step 595: f(x)= 2.135546908761359
# differential_evolution step 596: f(x)= 2.135546908761359
# differential_evolution step 597: f(x)= 2.135546908761359
# differential_evolution step 598: f(x)= 2.135546908761359
# differential_evolution step 599: f(x)= 2.135546908761359
# differential_evolution step 600: f(x)= 2.135546908761359
# differential_evolution step 601: f(x)= 2.135546908761359
# differential_evolution step 602: f(x)= 2.135546908761359
# differential_evolution step 603: f(x)= 2.1355160807704237
# differential_evolution step 604: f(x)= 2.1355160807704237
# differential_evolution step 605: f(x)= 2.1355160807704237
# differential_evolution step 606: f(x)= 2.135073022875738
# differential_evolution step 607: f(x)= 2.1346926248150355
# differential_evolution step 608: f(x)= 2.1346926248150355
# differential_evolution step 609: f(x)= 2.1346926248150355
# differential_evolution step 610: f(x)= 2.1346926248150355
# differential_evolution step 611: f(x)= 2.1346926248150355
# differential_evolution step 612: f(x)= 2.1346926248150355
# differential_evolution step 613: f(x)= 2.1346926248150355
# differential_evolution step 614: f(x)= 2.1346926248150355
# differential_evolution step 615: f(x)= 2.1346926248150355
# differential_evolution step 616: f(x)= 2.1346926248150355
# differential_evolution step 617: f(x)= 2.1346926248150355
# differential_evolution step 618: f(x)= 2.1346926248150355
# differential_evolution step 619: f(x)= 2.1346926248150355
# differential_evolution step 620: f(x)= 2.1346926248150355
# differential_evolution step 621: f(x)= 2.1346926248150355
# differential_evolution step 622: f(x)= 2.1346926248150355
# differential_evolution step 623: f(x)= 2.1346926248150355
# differential_evolution step 624: f(x)= 2.1346926248150355
# differential_evolution step 625: f(x)= 2.1346926248150355
# differential_evolution step 626: f(x)= 2.1346926248150355
# differential_evolution step 627: f(x)= 2.1346926248150355
# differential_evolution step 628: f(x)= 2.1346926248150355
# differential_evolution step 629: f(x)= 2.134676349071103
# differential_evolution step 630: f(x)= 2.134676349071103
# differential_evolution step 631: f(x)= 2.134676349071103
# differential_evolution step 632: f(x)= 2.134676349071103
# differential_evolution step 633: f(x)= 2.134676349071103
# differential_evolution step 634: f(x)= 2.134676349071103
# differential_evolution step 635: f(x)= 2.134676349071103
# differential_evolution step 636: f(x)= 2.134676349071103
# differential_evolution step 637: f(x)= 2.134676349071103
# differential_evolution step 638: f(x)= 2.134676349071103
# differential_evolution step 639: f(x)= 2.1346216850474504
# differential_evolution step 640: f(x)= 2.1346216850474504
# differential_evolution step 641: f(x)= 2.1346216850474504
# differential_evolution step 642: f(x)= 2.1346216850474504
# differential_evolution step 643: f(x)= 2.1346216850474504
# differential_evolution step 644: f(x)= 2.1346216850474504
# differential_evolution step 645: f(x)= 2.1346216850474504
# differential_evolution step 646: f(x)= 2.134615008520164
# differential_evolution step 647: f(x)= 2.134615008520164
# differential_evolution step 648: f(x)= 2.134615008520164
# differential_evolution step 649: f(x)= 2.134615008520164
# differential_evolution step 650: f(x)= 2.134615008520164
# differential_evolution step 651: f(x)= 2.134615008520164
# differential_evolution step 652: f(x)= 2.134615008520164
# differential_evolution step 653: f(x)= 2.134615008520164
# differential_evolution step 654: f(x)= 2.134615008520164
# differential_evolution step 655: f(x)= 2.134615008520164
# differential_evolution step 656: f(x)= 2.134615008520164
# differential_evolution step 657: f(x)= 2.134615008520164
# differential_evolution step 658: f(x)= 2.134615008520164
# differential_evolution step 659: f(x)= 2.134615008520164
# differential_evolution step 660: f(x)= 2.134615008520164
# differential_evolution step 661: f(x)= 2.134615008520164
# differential_evolution step 662: f(x)= 2.134615008520164
# differential_evolution step 663: f(x)= 2.134615008520164
# differential_evolution step 664: f(x)= 2.134615008520164
# differential_evolution step 665: f(x)= 2.134265680533525
# differential_evolution step 666: f(x)= 2.134265680533525
# differential_evolution step 667: f(x)= 2.134265680533525
# differential_evolution step 668: f(x)= 2.134265680533525
# differential_evolution step 669: f(x)= 2.134265680533525
# differential_evolution step 670: f(x)= 2.134265680533525
# differential_evolution step 671: f(x)= 2.134265680533525
# differential_evolution step 672: f(x)= 2.134265680533525
# differential_evolution step 673: f(x)= 2.134265680533525
# differential_evolution step 674: f(x)= 2.1341993775290105
# differential_evolution step 675: f(x)= 2.1341993775290105
# differential_evolution step 676: f(x)= 2.1341993775290105
# differential_evolution step 677: f(x)= 2.1341993775290105
# differential_evolution step 678: f(x)= 2.1341993775290105
# differential_evolution step 679: f(x)= 2.1338594162385394
# differential_evolution step 680: f(x)= 2.1338594162385394
# differential_evolution step 681: f(x)= 2.1338594162385394
# differential_evolution step 682: f(x)= 2.1338594162385394
# differential_evolution step 683: f(x)= 2.1338594162385394
# differential_evolution step 684: f(x)= 2.1338594162385394
# differential_evolution step 685: f(x)= 2.1338594162385394
# differential_evolution step 686: f(x)= 2.1336597065031753
# differential_evolution step 687: f(x)= 2.1336597065031753
# differential_evolution step 688: f(x)= 2.1336597065031753
# differential_evolution step 689: f(x)= 2.1336597065031753
# differential_evolution step 690: f(x)= 2.1336597065031753
# differential_evolution step 691: f(x)= 2.1336597065031753
# differential_evolution step 692: f(x)= 2.1336597065031753
# differential_evolution step 693: f(x)= 2.1334001120870143
# differential_evolution step 694: f(x)= 2.1334001120870143
# differential_evolution step 695: f(x)= 2.1334001120870143
# differential_evolution step 696: f(x)= 2.1334001120870143
# differential_evolution step 697: f(x)= 2.1334001120870143
# differential_evolution step 698: f(x)= 2.1334001120870143
# differential_evolution step 699: f(x)= 2.1334001120870143
# differential_evolution step 700: f(x)= 2.1333406132470683
# differential_evolution step 701: f(x)= 2.1333406132470683
# differential_evolution step 702: f(x)= 2.1333406132470683
# differential_evolution step 703: f(x)= 2.1333406132470683
# differential_evolution step 704: f(x)= 2.1333406132470683
# differential_evolution step 705: f(x)= 2.1333406132470683
# differential_evolution step 706: f(x)= 2.1333406132470683
# differential_evolution step 707: f(x)= 2.1333406132470683
# differential_evolution step 708: f(x)= 2.1333406132470683
# differential_evolution step 709: f(x)= 2.1333406132470683
# differential_evolution step 710: f(x)= 2.1333406132470683
# differential_evolution step 711: f(x)= 2.1333406132470683
# differential_evolution step 712: f(x)= 2.1333406132470683
# differential_evolution step 713: f(x)= 2.1333406132470683
# differential_evolution step 714: f(x)= 2.1333406132470683
# differential_evolution step 715: f(x)= 2.1333406132470683
# differential_evolution step 716: f(x)= 2.1333406132470683
# differential_evolution step 717: f(x)= 2.1333406132470683
# differential_evolution step 718: f(x)= 2.1333406132470683
# differential_evolution step 719: f(x)= 2.1333406132470683
# differential_evolution step 720: f(x)= 2.1333406132470683
# differential_evolution step 721: f(x)= 2.1331704745808375
# differential_evolution step 722: f(x)= 2.1331704745808375
# differential_evolution step 723: f(x)= 2.1331704745808375
# differential_evolution step 724: f(x)= 2.1331704745808375
# differential_evolution step 725: f(x)= 2.1331704745808375
# differential_evolution step 726: f(x)= 2.1331704745808375
# differential_evolution step 727: f(x)= 2.1331704745808375
# differential_evolution step 728: f(x)= 2.1331704745808375
# differential_evolution step 729: f(x)= 2.1331704745808375
# differential_evolution step 730: f(x)= 2.1331704745808375
# differential_evolution step 731: f(x)= 2.1331704745808375
# differential_evolution step 732: f(x)= 2.1331704745808375
# differential_evolution step 733: f(x)= 2.1331704745808375
# differential_evolution step 734: f(x)= 2.1331704745808375
# differential_evolution step 735: f(x)= 2.1331704745808375
# differential_evolution step 736: f(x)= 2.1331704745808375
# differential_evolution step 737: f(x)= 2.1331476812427987
# differential_evolution step 738: f(x)= 2.1331476812427987
# differential_evolution step 739: f(x)= 2.1331476812427987
# differential_evolution step 740: f(x)= 2.1331476812427987
# differential_evolution step 741: f(x)= 2.1331026017883747
# differential_evolution step 742: f(x)= 2.1331026017883747
# differential_evolution step 743: f(x)= 2.133096959729209
# differential_evolution step 744: f(x)= 2.133096959729209
# differential_evolution step 745: f(x)= 2.133023840495738
# differential_evolution step 746: f(x)= 2.133023840495738
# differential_evolution step 747: f(x)= 2.133023840495738
# differential_evolution step 748: f(x)= 2.133023840495738
# differential_evolution step 749: f(x)= 2.133023840495738
# differential_evolution step 750: f(x)= 2.1329659409307613
# differential_evolution step 751: f(x)= 2.1329659409307613
# differential_evolution step 752: f(x)= 2.1328834109708894
# differential_evolution step 753: f(x)= 2.1328834109708894
# differential_evolution step 754: f(x)= 2.1328834109708894
# differential_evolution step 755: f(x)= 2.132882624243351
# differential_evolution step 756: f(x)= 2.132882624243351
# differential_evolution step 757: f(x)= 2.132882624243351
# differential_evolution step 758: f(x)= 2.132882624243351
# differential_evolution step 759: f(x)= 2.132882624243351
# differential_evolution step 760: f(x)= 2.132880034714944
# differential_evolution step 761: f(x)= 2.132880034714944
# differential_evolution step 762: f(x)= 2.132880034714944
# differential_evolution step 763: f(x)= 2.132876669195525
# differential_evolution step 764: f(x)= 2.1328099413003954
# differential_evolution step 765: f(x)= 2.1328099413003954
# differential_evolution step 766: f(x)= 2.1328099413003954
# differential_evolution step 767: f(x)= 2.1328099413003954
# differential_evolution step 768: f(x)= 2.1328099413003954
# differential_evolution step 769: f(x)= 2.1328099413003954
# differential_evolution step 770: f(x)= 2.1328099413003954
# differential_evolution step 771: f(x)= 2.1328099413003954
# differential_evolution step 772: f(x)= 2.1328099413003954
# differential_evolution step 773: f(x)= 2.1328099413003954
# differential_evolution step 774: f(x)= 2.1328099413003954
# differential_evolution step 775: f(x)= 2.1328099413003954
# differential_evolution step 776: f(x)= 2.1328099413003954
# differential_evolution step 777: f(x)= 2.1328099413003954
# differential_evolution step 778: f(x)= 2.1328099413003954
# differential_evolution step 779: f(x)= 2.132803657531664
# differential_evolution step 780: f(x)= 2.132803657531664
# differential_evolution step 781: f(x)= 2.132803657531664
# differential_evolution step 782: f(x)= 2.132803657531664
# differential_evolution step 783: f(x)= 2.132803657531664
# differential_evolution step 784: f(x)= 2.132803657531664
# differential_evolution step 785: f(x)= 2.132803657531664
# differential_evolution step 786: f(x)= 2.132803657531664
# differential_evolution step 787: f(x)= 2.132803657531664
# differential_evolution step 788: f(x)= 2.132803657531664
# differential_evolution step 789: f(x)= 2.1327354063501067
# differential_evolution step 790: f(x)= 2.1327354063501067
# differential_evolution step 791: f(x)= 2.1327354063501067
# differential_evolution step 792: f(x)= 2.1327354063501067
# differential_evolution step 793: f(x)= 2.1327354063501067
# differential_evolution step 794: f(x)= 2.1327354063501067
# differential_evolution step 795: f(x)= 2.1327324876791085
# differential_evolution step 796: f(x)= 2.1327324876791085
# differential_evolution step 797: f(x)= 2.1326870645546085
# differential_evolution step 798: f(x)= 2.1326870645546085
# differential_evolution step 799: f(x)= 2.1326870645546085
# differential_evolution step 800: f(x)= 2.1326870645546085
# differential_evolution step 801: f(x)= 2.1326870645546085
# differential_evolution step 802: f(x)= 2.132684475038771
# differential_evolution step 803: f(x)= 2.132684475038771
# differential_evolution step 804: f(x)= 2.132684475038771
# differential_evolution step 805: f(x)= 2.132684475038771
# differential_evolution step 806: f(x)= 2.132684475038771
# differential_evolution step 807: f(x)= 2.132684475038771
# differential_evolution step 808: f(x)= 2.132684475038771
# differential_evolution step 809: f(x)= 2.132684475038771
# differential_evolution step 810: f(x)= 2.132684475038771
# differential_evolution step 811: f(x)= 2.132684475038771
# differential_evolution step 812: f(x)= 2.132684475038771
# differential_evolution step 813: f(x)= 2.132684475038771
# differential_evolution step 814: f(x)= 2.132684475038771
# differential_evolution step 815: f(x)= 2.132684475038771
# differential_evolution step 816: f(x)= 2.132684475038771
# differential_evolution step 817: f(x)= 2.132684475038771
# differential_evolution step 818: f(x)= 2.132684475038771
# differential_evolution step 819: f(x)= 2.132684475038771
# differential_evolution step 820: f(x)= 2.13267776624833
# differential_evolution step 821: f(x)= 2.13267776624833
# differential_evolution step 822: f(x)= 2.13267776624833
# differential_evolution step 823: f(x)= 2.1326724421806564
# differential_evolution step 824: f(x)= 2.1326553097981455
# differential_evolution step 825: f(x)= 2.1326553097981455
# differential_evolution step 826: f(x)= 2.132653265017919
# differential_evolution step 827: f(x)= 2.132653265017919
# differential_evolution step 828: f(x)= 2.132653265017919
# differential_evolution step 829: f(x)= 2.132653265017919
# differential_evolution step 830: f(x)= 2.132653265017919
# differential_evolution step 831: f(x)= 2.132653265017919
# differential_evolution step 832: f(x)= 2.132653265017919
# differential_evolution step 833: f(x)= 2.132653265017919
# differential_evolution step 834: f(x)= 2.1326272841227114
# differential_evolution step 835: f(x)= 2.1326272841227114
# differential_evolution step 836: f(x)= 2.1326272841227114
# differential_evolution step 837: f(x)= 2.1326272841227114
# differential_evolution step 838: f(x)= 2.1326272841227114
# differential_evolution step 839: f(x)= 2.1326272841227114
# differential_evolution step 840: f(x)= 2.1326272841227114
# differential_evolution step 841: f(x)= 2.1326272841227114
# differential_evolution step 842: f(x)= 2.1326272841227114
# differential_evolution step 843: f(x)= 2.1326272841227114
# differential_evolution step 844: f(x)= 2.1326272841227114
# differential_evolution step 845: f(x)= 2.1326272841227114
# differential_evolution step 846: f(x)= 2.1326272841227114
# differential_evolution step 847: f(x)= 2.1326272841227114
# differential_evolution step 848: f(x)= 2.1326272841227114
# differential_evolution step 849: f(x)= 2.1326272841227114
# differential_evolution step 850: f(x)= 2.1326272841227114
# differential_evolution step 851: f(x)= 2.1326272841227114
# differential_evolution step 852: f(x)= 2.1326272841227114
# differential_evolution step 853: f(x)= 2.1326272841227114
# differential_evolution step 854: f(x)= 2.1326272841227114
# differential_evolution step 855: f(x)= 2.1326272841227114
# differential_evolution step 856: f(x)= 2.1326272841227114
# differential_evolution step 857: f(x)= 2.1326272841227114
# differential_evolution step 858: f(x)= 2.1326272841227114
# differential_evolution step 859: f(x)= 2.1326272841227114
# differential_evolution step 860: f(x)= 2.1326272841227114
# differential_evolution step 861: f(x)= 2.1326272841227114
# differential_evolution step 862: f(x)= 2.1326272841227114
# differential_evolution step 863: f(x)= 2.1326272841227114
# differential_evolution step 864: f(x)= 2.132605257844676
# differential_evolution step 865: f(x)= 2.132605257844676
# differential_evolution step 866: f(x)= 2.132605257844676
# differential_evolution step 867: f(x)= 2.132605257844676
# differential_evolution step 868: f(x)= 2.132605257844676
# differential_evolution step 869: f(x)= 2.132605257844676
# differential_evolution step 870: f(x)= 2.132605257844676
# differential_evolution step 871: f(x)= 2.132605257844676
# differential_evolution step 872: f(x)= 2.132605257844676
# differential_evolution step 873: f(x)= 2.132605257844676
# differential_evolution step 874: f(x)= 2.132605257844676
# differential_evolution step 875: f(x)= 2.132605257844676
# differential_evolution step 876: f(x)= 2.132605257844676
# differential_evolution step 877: f(x)= 2.132605257844676
# differential_evolution step 878: f(x)= 2.132605257844676
# differential_evolution step 879: f(x)= 2.132605257844676
# differential_evolution step 880: f(x)= 2.132605257844676
# differential_evolution step 881: f(x)= 2.132605257844676
# differential_evolution step 882: f(x)= 2.132605257844676
# differential_evolution step 883: f(x)= 2.132605257844676
# differential_evolution step 884: f(x)= 2.132605257844676
# differential_evolution step 885: f(x)= 2.132605257844676
# differential_evolution step 886: f(x)= 2.132605257844676
# differential_evolution step 887: f(x)= 2.132605257844676
# differential_evolution step 888: f(x)= 2.132605257844676
# differential_evolution step 889: f(x)= 2.132605257844676
# differential_evolution step 890: f(x)= 2.132605257844676
# differential_evolution step 891: f(x)= 2.132605257844676
# differential_evolution step 892: f(x)= 2.1326001149958302
# differential_evolution step 893: f(x)= 2.1326001149958302
# differential_evolution step 894: f(x)= 2.1326001149958302
# differential_evolution step 895: f(x)= 2.1326001149958302
# differential_evolution step 896: f(x)= 2.1326001149958302
# differential_evolution step 897: f(x)= 2.1326001149958302
# differential_evolution step 898: f(x)= 2.1326001149958302
# differential_evolution step 899: f(x)= 2.1325970522549573
# differential_evolution step 900: f(x)= 2.1325970522549573
# differential_evolution step 901: f(x)= 2.1325970522549573
# differential_evolution step 902: f(x)= 2.1325970522549573
# differential_evolution step 903: f(x)= 2.1325970522549573
# differential_evolution step 904: f(x)= 2.1325970522549573
# differential_evolution step 905: f(x)= 2.1325970522549573
# differential_evolution step 906: f(x)= 2.1325970522549573
# differential_evolution step 907: f(x)= 2.1325970522549573
# differential_evolution step 908: f(x)= 2.1325970522549573
# differential_evolution step 909: f(x)= 2.1325970522549573
# differential_evolution step 910: f(x)= 2.1325970522549573
# differential_evolution step 911: f(x)= 2.1325970522549573
# differential_evolution step 912: f(x)= 2.1325970522549573
# differential_evolution step 913: f(x)= 2.1325970522549573
# differential_evolution step 914: f(x)= 2.1325970522549573
# differential_evolution step 915: f(x)= 2.1325970522549573
# differential_evolution step 916: f(x)= 2.1325970522549573
# differential_evolution step 917: f(x)= 2.132592897678769
# differential_evolution step 918: f(x)= 2.132590352182229
# differential_evolution step 919: f(x)= 2.132590352182229
# differential_evolution step 920: f(x)= 2.1325866021088458
# differential_evolution step 921: f(x)= 2.132586229140967
# differential_evolution step 922: f(x)= 2.132586229140967
# differential_evolution step 923: f(x)= 2.132586229140967
# differential_evolution step 924: f(x)= 2.132586229140967
# differential_evolution step 925: f(x)= 2.132586229140967
# differential_evolution step 926: f(x)= 2.132586229140967
# differential_evolution step 927: f(x)= 2.132586229140967
# differential_evolution step 928: f(x)= 2.132586229140967
# differential_evolution step 929: f(x)= 2.132586229140967
# differential_evolution step 930: f(x)= 2.132586229140967
# differential_evolution step 931: f(x)= 2.132586229140967
# differential_evolution step 932: f(x)= 2.132586229140967
# differential_evolution step 933: f(x)= 2.132586229140967
# differential_evolution step 934: f(x)= 2.132586229140967
# differential_evolution step 935: f(x)= 2.132586229140967
# differential_evolution step 936: f(x)= 2.132586229140967
# differential_evolution step 937: f(x)= 2.132586229140967
# differential_evolution step 938: f(x)= 2.132586229140967
# differential_evolution step 939: f(x)= 2.132586229140967
# differential_evolution step 940: f(x)= 2.132586229140967
# differential_evolution step 941: f(x)= 2.132586229140967
# differential_evolution step 942: f(x)= 2.1325856650787944
# differential_evolution step 943: f(x)= 2.1325856650787944
# differential_evolution step 944: f(x)= 2.1325856650787944
# differential_evolution step 945: f(x)= 2.1325856650787944
# differential_evolution step 946: f(x)= 2.132585416097011
# differential_evolution step 947: f(x)= 2.132585416097011
# differential_evolution step 948: f(x)= 2.132583299335399
# differential_evolution step 949: f(x)= 2.132583299335399
# differential_evolution step 950: f(x)= 2.132583299335399
# differential_evolution step 951: f(x)= 2.132583299335399
# differential_evolution step 952: f(x)= 2.132583299335399
# differential_evolution step 953: f(x)= 2.132583299335399
# differential_evolution step 954: f(x)= 2.132583299335399
# differential_evolution step 955: f(x)= 2.132583299335399
# differential_evolution step 956: f(x)= 2.132583299335399
# differential_evolution step 957: f(x)= 2.132583299335399
# differential_evolution step 958: f(x)= 2.132583299335399
# differential_evolution step 959: f(x)= 2.132583299335399
# differential_evolution step 960: f(x)= 2.132583299335399
# differential_evolution step 961: f(x)= 2.132583299335399
# differential_evolution step 962: f(x)= 2.132583299335399
# differential_evolution step 963: f(x)= 2.132583299335399
# differential_evolution step 964: f(x)= 2.132583299335399
# differential_evolution step 965: f(x)= 2.132583299335399
# differential_evolution step 966: f(x)= 2.1325819527166
# differential_evolution step 967: f(x)= 2.1325819527166
# differential_evolution step 968: f(x)= 2.132581775925449
# differential_evolution step 969: f(x)= 2.132581775925449
# differential_evolution step 970: f(x)= 2.132581775925449
# differential_evolution step 971: f(x)= 2.1325806195974497
# differential_evolution step 972: f(x)= 2.1325806195974497
# differential_evolution step 973: f(x)= 2.1325806195974497
# differential_evolution step 974: f(x)= 2.1325806195974497
# differential_evolution step 975: f(x)= 2.1325806195974497
# differential_evolution step 976: f(x)= 2.1325806195974497
# differential_evolution step 977: f(x)= 2.1325806195974497
# differential_evolution step 978: f(x)= 2.1325805005768887
# differential_evolution step 979: f(x)= 2.1325805005768887
# differential_evolution step 980: f(x)= 2.1325786727807277
# differential_evolution step 981: f(x)= 2.1325786727807277
# differential_evolution step 982: f(x)= 2.1325786727807277
# differential_evolution step 983: f(x)= 2.132578633463278
# differential_evolution step 984: f(x)= 2.132578633463278
# differential_evolution step 985: f(x)= 2.132578633463278
# differential_evolution step 986: f(x)= 2.132578633463278
# differential_evolution step 987: f(x)= 2.132578633463278
# differential_evolution step 988: f(x)= 2.132578633463278
# differential_evolution step 989: f(x)= 2.132578633463278
# differential_evolution step 990: f(x)= 2.132578633463278
# differential_evolution step 991: f(x)= 2.132578633463278
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.87409678e+00 4.71218717e+00 1.48099008e+00 3.27370470e+01
#  2.45116150e-02 4.99996955e+01 2.78706596e+00 7.02870718e+01
#  4.21662839e-01 3.95199033e+00 1.00005703e-01 1.77540264e+01
#  1.90103534e-01 3.81273621e+01 1.00001432e-01 2.09997605e+01]
# Chi quadro minimo: 2.132578633463278

# %%
# Plots:
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, 
                                         sigma = radial_profile_error_HA, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.0035, r_e=7.0166, n=1.9896, x_0=32.8307
# Sérsic 2: I_e=0.0293, r_e=50.0000, n=2.5352, x_0=69.9895
# Sérsic 3: I_e=0.4224, r_e=4.0088, n=0.1036, x_0=17.3556
# Sérsic 4: I_e=0.0959, r_e=39.0862, n=0.1024, x_0=20.3097
# [2.72687897e-01 1.23487458e+00 2.26121056e-01 4.82332548e-02
#  3.92373601e-02 4.56506784e+01 1.43940659e+00 1.08519192e-02
#  3.08100250e-01 3.94007847e+00 2.89310211e-01 4.19511244e-01
#  6.55930718e-01 1.37569762e+03 2.95330541e+00 1.19018377e+03]
# 69.28182729714538
# 106.56338069520363 69.28182729714538 145.88169518165813 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (68, 73),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (19, 22),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 56757.61203586566
# differential_evolution step 2: f(x)= 29573.004277966786
# differential_evolution step 3: f(x)= 7896.967075080005
# differential_evolution step 4: f(x)= 7896.967075080005
# differential_evolution step 5: f(x)= 6448.698127855476
# differential_evolution step 6: f(x)= 6448.698127855476
# differential_evolution step 7: f(x)= 6448.698127855476
# differential_evolution step 8: f(x)= 3230.071944353572
# differential_evolution step 9: f(x)= 3230.071944353572
# differential_evolution step 10: f(x)= 3230.071944353572
# differential_evolution step 11: f(x)= 2524.770018577745
# differential_evolution step 12: f(x)= 1046.6361420898063
# differential_evolution step 13: f(x)= 934.5555444007263
# differential_evolution step 14: f(x)= 934.5555444007263
# differential_evolution step 15: f(x)= 404.16164240499864
# differential_evolution step 16: f(x)= 404.16164240499864
# differential_evolution step 17: f(x)= 404.16164240499864
# differential_evolution step 18: f(x)= 404.16164240499864
# differential_evolution step 19: f(x)= 404.16164240499864
# differential_evolution step 20: f(x)= 404.16164240499864
# differential_evolution step 21: f(x)= 76.55752322499471
# differential_evolution step 22: f(x)= 76.55752322499471
# differential_evolution step 23: f(x)= 76.55752322499471
# differential_evolution step 24: f(x)= 76.55752322499471
# differential_evolution step 25: f(x)= 76.55752322499471
# differential_evolution step 26: f(x)= 76.55752322499471
# differential_evolution step 27: f(x)= 76.55752322499471
# differential_evolution step 28: f(x)= 76.55752322499471
# differential_evolution step 29: f(x)= 76.55752322499471
# differential_evolution step 30: f(x)= 76.55752322499471
# differential_evolution step 31: f(x)= 76.55752322499471
# differential_evolution step 32: f(x)= 76.55752322499471
# differential_evolution step 33: f(x)= 76.55752322499471
# differential_evolution step 34: f(x)= 41.674362080840034
# differential_evolution step 35: f(x)= 41.674362080840034
# differential_evolution step 36: f(x)= 41.674362080840034
# differential_evolution step 37: f(x)= 21.29602859878785
# differential_evolution step 38: f(x)= 21.29602859878785
# differential_evolution step 39: f(x)= 21.29602859878785
# differential_evolution step 40: f(x)= 21.29602859878785
# differential_evolution step 41: f(x)= 21.29602859878785
# differential_evolution step 42: f(x)= 21.29602859878785
# differential_evolution step 43: f(x)= 21.29602859878785
# differential_evolution step 44: f(x)= 21.29602859878785
# differential_evolution step 45: f(x)= 21.29602859878785
# differential_evolution step 46: f(x)= 21.29602859878785
# differential_evolution step 47: f(x)= 21.29602859878785
# differential_evolution step 48: f(x)= 21.29602859878785
# differential_evolution step 49: f(x)= 21.29602859878785
# differential_evolution step 50: f(x)= 21.29602859878785
# differential_evolution step 51: f(x)= 21.29602859878785
# differential_evolution step 52: f(x)= 21.29602859878785
# differential_evolution step 53: f(x)= 21.29602859878785
# differential_evolution step 54: f(x)= 21.29602859878785
# differential_evolution step 55: f(x)= 21.29602859878785
# differential_evolution step 56: f(x)= 21.29602859878785
# differential_evolution step 57: f(x)= 21.29602859878785
# differential_evolution step 58: f(x)= 21.29602859878785
# differential_evolution step 59: f(x)= 21.29602859878785
# differential_evolution step 60: f(x)= 21.29602859878785
# differential_evolution step 61: f(x)= 21.29602859878785
# differential_evolution step 62: f(x)= 21.29602859878785
# differential_evolution step 63: f(x)= 21.29602859878785
# differential_evolution step 64: f(x)= 21.29602859878785
# differential_evolution step 65: f(x)= 21.29602859878785
# differential_evolution step 66: f(x)= 21.29602859878785
# differential_evolution step 67: f(x)= 21.29602859878785
# differential_evolution step 68: f(x)= 21.29602859878785
# differential_evolution step 69: f(x)= 21.29602859878785
# differential_evolution step 70: f(x)= 21.29602859878785
# differential_evolution step 71: f(x)= 19.599897913656726
# differential_evolution step 72: f(x)= 19.599897913656726
# differential_evolution step 73: f(x)= 13.28776575559996
# differential_evolution step 74: f(x)= 13.28776575559996
# differential_evolution step 75: f(x)= 13.28776575559996
# differential_evolution step 76: f(x)= 13.28776575559996
# differential_evolution step 77: f(x)= 13.28776575559996
# differential_evolution step 78: f(x)= 13.28776575559996
# differential_evolution step 79: f(x)= 13.28776575559996
# differential_evolution step 80: f(x)= 13.28776575559996
# differential_evolution step 81: f(x)= 13.28776575559996
# differential_evolution step 82: f(x)= 13.28776575559996
# differential_evolution step 83: f(x)= 13.28776575559996
# differential_evolution step 84: f(x)= 13.28776575559996
# differential_evolution step 85: f(x)= 13.28776575559996
# differential_evolution step 86: f(x)= 12.847098664282065
# differential_evolution step 87: f(x)= 12.847098664282065
# differential_evolution step 88: f(x)= 12.847098664282065
# differential_evolution step 89: f(x)= 12.847098664282065
# differential_evolution step 90: f(x)= 12.847098664282065
# differential_evolution step 91: f(x)= 12.847098664282065
# differential_evolution step 92: f(x)= 12.847098664282065
# differential_evolution step 93: f(x)= 9.890354721739346
# differential_evolution step 94: f(x)= 9.890354721739346
# differential_evolution step 95: f(x)= 9.890354721739346
# differential_evolution step 96: f(x)= 9.628244924664527
# differential_evolution step 97: f(x)= 9.628244924664527
# differential_evolution step 98: f(x)= 9.628244924664527
# differential_evolution step 99: f(x)= 9.628244924664527
# differential_evolution step 100: f(x)= 9.628244924664527
# differential_evolution step 101: f(x)= 9.628244924664527
# differential_evolution step 102: f(x)= 9.628244924664527
# differential_evolution step 103: f(x)= 9.628244924664527
# differential_evolution step 104: f(x)= 9.628244924664527
# differential_evolution step 105: f(x)= 9.628244924664527
# differential_evolution step 106: f(x)= 9.628244924664527
# differential_evolution step 107: f(x)= 6.387025163033001
# differential_evolution step 108: f(x)= 6.387025163033001
# differential_evolution step 109: f(x)= 6.387025163033001
# differential_evolution step 110: f(x)= 6.387025163033001
# differential_evolution step 111: f(x)= 6.387025163033001
# differential_evolution step 112: f(x)= 6.387025163033001
# differential_evolution step 113: f(x)= 6.387025163033001
# differential_evolution step 114: f(x)= 6.387025163033001
# differential_evolution step 115: f(x)= 6.387025163033001
# differential_evolution step 116: f(x)= 3.5813911330357606
# differential_evolution step 117: f(x)= 3.5813911330357606
# differential_evolution step 118: f(x)= 3.5813911330357606
# differential_evolution step 119: f(x)= 3.5813911330357606
# differential_evolution step 120: f(x)= 3.5813911330357606
# differential_evolution step 121: f(x)= 3.5813911330357606
# differential_evolution step 122: f(x)= 3.5813911330357606
# differential_evolution step 123: f(x)= 3.5813911330357606
# differential_evolution step 124: f(x)= 3.5813911330357606
# differential_evolution step 125: f(x)= 3.5813911330357606
# differential_evolution step 126: f(x)= 3.5813911330357606
# differential_evolution step 127: f(x)= 3.5813911330357606
# differential_evolution step 128: f(x)= 3.5813911330357606
# differential_evolution step 129: f(x)= 3.5813911330357606
# differential_evolution step 130: f(x)= 3.5813911330357606
# differential_evolution step 131: f(x)= 3.5813911330357606
# differential_evolution step 132: f(x)= 3.5813911330357606
# differential_evolution step 133: f(x)= 3.2915586076447343
# differential_evolution step 134: f(x)= 3.2915586076447343
# differential_evolution step 135: f(x)= 3.2915586076447343
# differential_evolution step 136: f(x)= 3.2915586076447343
# differential_evolution step 137: f(x)= 3.2915586076447343
# differential_evolution step 138: f(x)= 3.2915586076447343
# differential_evolution step 139: f(x)= 3.2915586076447343
# differential_evolution step 140: f(x)= 3.2915586076447343
# differential_evolution step 141: f(x)= 3.2915586076447343
# differential_evolution step 142: f(x)= 3.2915586076447343
# differential_evolution step 143: f(x)= 3.2915586076447343
# differential_evolution step 144: f(x)= 3.2915586076447343
# differential_evolution step 145: f(x)= 2.9544595460863423
# differential_evolution step 146: f(x)= 2.9544595460863423
# differential_evolution step 147: f(x)= 2.9544595460863423
# differential_evolution step 148: f(x)= 2.9544595460863423
# differential_evolution step 149: f(x)= 2.9544595460863423
# differential_evolution step 150: f(x)= 2.9544595460863423
# differential_evolution step 151: f(x)= 2.9544595460863423
# differential_evolution step 152: f(x)= 2.9544595460863423
# differential_evolution step 153: f(x)= 2.9544595460863423
# differential_evolution step 154: f(x)= 2.9544595460863423
# differential_evolution step 155: f(x)= 2.9544595460863423
# differential_evolution step 156: f(x)= 2.9544595460863423
# differential_evolution step 157: f(x)= 2.9544595460863423
# differential_evolution step 158: f(x)= 2.8485207373389856
# differential_evolution step 159: f(x)= 2.7952376193729136
# differential_evolution step 160: f(x)= 2.751408024797149
# differential_evolution step 161: f(x)= 2.751408024797149
# differential_evolution step 162: f(x)= 2.751408024797149
# differential_evolution step 163: f(x)= 2.751408024797149
# differential_evolution step 164: f(x)= 2.5399247548444626
# differential_evolution step 165: f(x)= 2.5399247548444626
# differential_evolution step 166: f(x)= 2.5399247548444626
# differential_evolution step 167: f(x)= 2.5399247548444626
# differential_evolution step 168: f(x)= 2.5399247548444626
# differential_evolution step 169: f(x)= 2.5399247548444626
# differential_evolution step 170: f(x)= 2.5399247548444626
# differential_evolution step 171: f(x)= 2.5399247548444626
# differential_evolution step 172: f(x)= 2.5399247548444626
# differential_evolution step 173: f(x)= 2.5399247548444626
# differential_evolution step 174: f(x)= 2.5399247548444626
# differential_evolution step 175: f(x)= 2.5399247548444626
# differential_evolution step 176: f(x)= 2.5399247548444626
# differential_evolution step 177: f(x)= 2.5399247548444626
# differential_evolution step 178: f(x)= 2.5399247548444626
# differential_evolution step 179: f(x)= 2.5399247548444626
# differential_evolution step 180: f(x)= 2.5399247548444626
# differential_evolution step 181: f(x)= 2.5399247548444626
# differential_evolution step 182: f(x)= 2.5399247548444626
# differential_evolution step 183: f(x)= 2.5399247548444626
# differential_evolution step 184: f(x)= 2.5399247548444626
# differential_evolution step 185: f(x)= 2.5399247548444626
# differential_evolution step 186: f(x)= 2.5399247548444626
# differential_evolution step 187: f(x)= 2.5399247548444626
# differential_evolution step 188: f(x)= 2.5399247548444626
# differential_evolution step 189: f(x)= 2.481234469896556
# differential_evolution step 190: f(x)= 2.481234469896556
# differential_evolution step 191: f(x)= 2.481234469896556
# differential_evolution step 192: f(x)= 2.481234469896556
# differential_evolution step 193: f(x)= 2.4155174853408834
# differential_evolution step 194: f(x)= 2.4155174853408834
# differential_evolution step 195: f(x)= 2.4155174853408834
# differential_evolution step 196: f(x)= 1.7541131763052071
# differential_evolution step 197: f(x)= 1.7541131763052071
# differential_evolution step 198: f(x)= 1.7541131763052071
# differential_evolution step 199: f(x)= 1.6909449512912604
# differential_evolution step 200: f(x)= 1.6909449512912604
# differential_evolution step 201: f(x)= 1.6909449512912604
# differential_evolution step 202: f(x)= 1.6909449512912604
# differential_evolution step 203: f(x)= 1.6909449512912604
# differential_evolution step 204: f(x)= 1.6909449512912604
# differential_evolution step 205: f(x)= 1.6909449512912604
# differential_evolution step 206: f(x)= 1.6909449512912604
# differential_evolution step 207: f(x)= 1.6909449512912604
# differential_evolution step 208: f(x)= 1.6909449512912604
# differential_evolution step 209: f(x)= 1.6909449512912604
# differential_evolution step 210: f(x)= 1.6909449512912604
# differential_evolution step 211: f(x)= 1.6909449512912604
# differential_evolution step 212: f(x)= 1.6909449512912604
# differential_evolution step 213: f(x)= 1.6909449512912604
# differential_evolution step 214: f(x)= 1.6909449512912604
# differential_evolution step 215: f(x)= 1.6909449512912604
# differential_evolution step 216: f(x)= 1.6909449512912604
# differential_evolution step 217: f(x)= 1.6909449512912604
# differential_evolution step 218: f(x)= 1.6909449512912604
# differential_evolution step 219: f(x)= 1.4730406639402573
# differential_evolution step 220: f(x)= 1.4730406639402573
# differential_evolution step 221: f(x)= 1.4730406639402573
# differential_evolution step 222: f(x)= 1.4730406639402573
# differential_evolution step 223: f(x)= 1.4730406639402573
# differential_evolution step 224: f(x)= 1.4730406639402573
# differential_evolution step 225: f(x)= 1.4730406639402573
# differential_evolution step 226: f(x)= 1.4730406639402573
# differential_evolution step 227: f(x)= 1.4730406639402573
# differential_evolution step 228: f(x)= 1.4730406639402573
# differential_evolution step 229: f(x)= 1.4730406639402573
# differential_evolution step 230: f(x)= 1.4730406639402573
# differential_evolution step 231: f(x)= 1.4730406639402573
# differential_evolution step 232: f(x)= 1.4730406639402573
# differential_evolution step 233: f(x)= 1.4730406639402573
# differential_evolution step 234: f(x)= 1.4730406639402573
# differential_evolution step 235: f(x)= 1.4730406639402573
# differential_evolution step 236: f(x)= 1.4730406639402573
# differential_evolution step 237: f(x)= 1.4730406639402573
# differential_evolution step 238: f(x)= 1.4730406639402573
# differential_evolution step 239: f(x)= 1.4730406639402573
# differential_evolution step 240: f(x)= 1.4730406639402573
# differential_evolution step 241: f(x)= 1.4730406639402573
# differential_evolution step 242: f(x)= 1.4730406639402573
# differential_evolution step 243: f(x)= 1.4730406639402573
# differential_evolution step 244: f(x)= 1.4730406639402573
# differential_evolution step 245: f(x)= 1.4730406639402573
# differential_evolution step 246: f(x)= 1.4730406639402573
# differential_evolution step 247: f(x)= 1.4730406639402573
# differential_evolution step 248: f(x)= 1.4730406639402573
# differential_evolution step 249: f(x)= 1.4730406639402573
# differential_evolution step 250: f(x)= 1.4730406639402573
# differential_evolution step 251: f(x)= 1.4730406639402573
# differential_evolution step 252: f(x)= 1.4730406639402573
# differential_evolution step 253: f(x)= 1.4639425585603698
# differential_evolution step 254: f(x)= 1.4639425585603698
# differential_evolution step 255: f(x)= 1.4639425585603698
# differential_evolution step 256: f(x)= 1.4639425585603698
# differential_evolution step 257: f(x)= 1.4639425585603698
# differential_evolution step 258: f(x)= 1.4639425585603698
# differential_evolution step 259: f(x)= 1.4639425585603698
# differential_evolution step 260: f(x)= 1.4639425585603698
# differential_evolution step 261: f(x)= 1.4639425585603698
# differential_evolution step 262: f(x)= 1.4639425585603698
# differential_evolution step 263: f(x)= 1.4639425585603698
# differential_evolution step 264: f(x)= 1.4639425585603698
# differential_evolution step 265: f(x)= 1.4639425585603698
# differential_evolution step 266: f(x)= 1.4639425585603698
# differential_evolution step 267: f(x)= 1.4639425585603698
# differential_evolution step 268: f(x)= 1.4639425585603698
# differential_evolution step 269: f(x)= 1.4639425585603698
# differential_evolution step 270: f(x)= 1.4639425585603698
# differential_evolution step 271: f(x)= 1.4639425585603698
# differential_evolution step 272: f(x)= 1.4639425585603698
# differential_evolution step 273: f(x)= 1.4639425585603698
# differential_evolution step 274: f(x)= 1.4639425585603698
# differential_evolution step 275: f(x)= 1.4639425585603698
# differential_evolution step 276: f(x)= 1.4639425585603698
# differential_evolution step 277: f(x)= 1.4639425585603698
# differential_evolution step 278: f(x)= 1.4639425585603698
# differential_evolution step 279: f(x)= 1.4639425585603698
# differential_evolution step 280: f(x)= 1.4639425585603698
# differential_evolution step 281: f(x)= 1.4639425585603698
# differential_evolution step 282: f(x)= 1.4639425585603698
# differential_evolution step 283: f(x)= 1.4097394198483557
# differential_evolution step 284: f(x)= 1.3856266726958055
# differential_evolution step 285: f(x)= 1.3856266726958055
# differential_evolution step 286: f(x)= 1.3856266726958055
# differential_evolution step 287: f(x)= 1.3856266726958055
# differential_evolution step 288: f(x)= 1.3856266726958055
# differential_evolution step 289: f(x)= 1.3856266726958055
# differential_evolution step 290: f(x)= 1.3856266726958055
# differential_evolution step 291: f(x)= 1.3856266726958055
# differential_evolution step 292: f(x)= 1.3856266726958055
# differential_evolution step 293: f(x)= 1.3856266726958055
# differential_evolution step 294: f(x)= 1.3856266726958055
# differential_evolution step 295: f(x)= 1.3856266726958055
# differential_evolution step 296: f(x)= 1.3856266726958055
# differential_evolution step 297: f(x)= 1.3856266726958055
# differential_evolution step 298: f(x)= 1.3856266726958055
# differential_evolution step 299: f(x)= 1.3856266726958055
# differential_evolution step 300: f(x)= 1.3856266726958055
# differential_evolution step 301: f(x)= 1.3856266726958055
# differential_evolution step 302: f(x)= 1.3856266726958055
# differential_evolution step 303: f(x)= 1.3856266726958055
# differential_evolution step 304: f(x)= 1.378123377874803
# differential_evolution step 305: f(x)= 1.378123377874803
# differential_evolution step 306: f(x)= 1.378123377874803
# differential_evolution step 307: f(x)= 1.378123377874803
# differential_evolution step 308: f(x)= 1.378123377874803
# differential_evolution step 309: f(x)= 1.378123377874803
# differential_evolution step 310: f(x)= 1.378123377874803
# differential_evolution step 311: f(x)= 1.378123377874803
# differential_evolution step 312: f(x)= 1.378123377874803
# differential_evolution step 313: f(x)= 1.378123377874803
# differential_evolution step 314: f(x)= 1.378123377874803
# differential_evolution step 315: f(x)= 1.378123377874803
# differential_evolution step 316: f(x)= 1.378123377874803
# differential_evolution step 317: f(x)= 1.378123377874803
# differential_evolution step 318: f(x)= 1.378123377874803
# differential_evolution step 319: f(x)= 1.378123377874803
# differential_evolution step 320: f(x)= 1.378123377874803
# differential_evolution step 321: f(x)= 1.378123377874803
# differential_evolution step 322: f(x)= 1.378123377874803
# differential_evolution step 323: f(x)= 1.378123377874803
# differential_evolution step 324: f(x)= 1.2944324820610134
# differential_evolution step 325: f(x)= 1.2502532059328955
# differential_evolution step 326: f(x)= 1.2502532059328955
# differential_evolution step 327: f(x)= 1.2502532059328955
# differential_evolution step 328: f(x)= 1.2502532059328955
# differential_evolution step 329: f(x)= 1.2502532059328955
# differential_evolution step 330: f(x)= 1.2502532059328955
# differential_evolution step 331: f(x)= 1.2502532059328955
# differential_evolution step 332: f(x)= 1.2502532059328955
# differential_evolution step 333: f(x)= 1.2502532059328955
# differential_evolution step 334: f(x)= 1.2502532059328955
# differential_evolution step 335: f(x)= 1.2502532059328955
# differential_evolution step 336: f(x)= 1.2502532059328955
# differential_evolution step 337: f(x)= 1.2502532059328955
# differential_evolution step 338: f(x)= 1.2502532059328955
# differential_evolution step 339: f(x)= 1.2502532059328955
# differential_evolution step 340: f(x)= 1.223103030945321
# differential_evolution step 341: f(x)= 1.223103030945321
# differential_evolution step 342: f(x)= 1.223103030945321
# differential_evolution step 343: f(x)= 1.223103030945321
# differential_evolution step 344: f(x)= 1.210200568661507
# differential_evolution step 345: f(x)= 1.210200568661507
# differential_evolution step 346: f(x)= 1.210200568661507
# differential_evolution step 347: f(x)= 1.210200568661507
# differential_evolution step 348: f(x)= 1.210200568661507
# differential_evolution step 349: f(x)= 1.210200568661507
# differential_evolution step 350: f(x)= 1.210200568661507
# differential_evolution step 351: f(x)= 1.210200568661507
# differential_evolution step 352: f(x)= 1.210200568661507
# differential_evolution step 353: f(x)= 1.210200568661507
# differential_evolution step 354: f(x)= 1.210200568661507
# differential_evolution step 355: f(x)= 1.210200568661507
# differential_evolution step 356: f(x)= 1.175483928780729
# differential_evolution step 357: f(x)= 1.175483928780729
# differential_evolution step 358: f(x)= 1.175483928780729
# differential_evolution step 359: f(x)= 1.175483928780729
# differential_evolution step 360: f(x)= 1.175483928780729
# differential_evolution step 361: f(x)= 1.175483928780729
# differential_evolution step 362: f(x)= 1.175483928780729
# differential_evolution step 363: f(x)= 1.175483928780729
# differential_evolution step 364: f(x)= 1.1678799985436163
# differential_evolution step 365: f(x)= 1.1678799985436163
# differential_evolution step 366: f(x)= 1.1678799985436163
# differential_evolution step 367: f(x)= 1.1678799985436163
# differential_evolution step 368: f(x)= 1.1678799985436163
# differential_evolution step 369: f(x)= 1.1678799985436163
# differential_evolution step 370: f(x)= 1.1678799985436163
# differential_evolution step 371: f(x)= 1.1678799985436163
# differential_evolution step 372: f(x)= 1.1678799985436163
# differential_evolution step 373: f(x)= 1.1678799985436163
# differential_evolution step 374: f(x)= 1.1678799985436163
# differential_evolution step 375: f(x)= 1.1678799985436163
# differential_evolution step 376: f(x)= 1.1678799985436163
# differential_evolution step 377: f(x)= 1.1678799985436163
# differential_evolution step 378: f(x)= 1.1678799985436163
# differential_evolution step 379: f(x)= 1.164354490226315
# differential_evolution step 380: f(x)= 1.164354490226315
# differential_evolution step 381: f(x)= 1.164354490226315
# differential_evolution step 382: f(x)= 1.164354490226315
# differential_evolution step 383: f(x)= 1.164354490226315
# differential_evolution step 384: f(x)= 1.164354490226315
# differential_evolution step 385: f(x)= 1.164354490226315
# differential_evolution step 386: f(x)= 1.164354490226315
# differential_evolution step 387: f(x)= 1.164354490226315
# differential_evolution step 388: f(x)= 1.164354490226315
# differential_evolution step 389: f(x)= 1.164354490226315
# differential_evolution step 390: f(x)= 1.164354490226315
# differential_evolution step 391: f(x)= 1.164354490226315
# differential_evolution step 392: f(x)= 1.164354490226315
# differential_evolution step 393: f(x)= 1.164354490226315
# differential_evolution step 394: f(x)= 1.164354490226315
# differential_evolution step 395: f(x)= 1.164354490226315
# differential_evolution step 396: f(x)= 1.1420335153170496
# differential_evolution step 397: f(x)= 1.1420335153170496
# differential_evolution step 398: f(x)= 1.1420335153170496
# differential_evolution step 399: f(x)= 1.1420335153170496
# differential_evolution step 400: f(x)= 1.1420335153170496
# differential_evolution step 401: f(x)= 1.1420335153170496
# differential_evolution step 402: f(x)= 1.1420335153170496
# differential_evolution step 403: f(x)= 1.1420335153170496
# differential_evolution step 404: f(x)= 1.1420335153170496
# differential_evolution step 405: f(x)= 1.1420335153170496
# differential_evolution step 406: f(x)= 1.1420335153170496
# differential_evolution step 407: f(x)= 1.1420335153170496
# differential_evolution step 408: f(x)= 1.0996722508931016
# differential_evolution step 409: f(x)= 1.0996722508931016
# differential_evolution step 410: f(x)= 1.0996722508931016
# differential_evolution step 411: f(x)= 1.0952060443994376
# differential_evolution step 412: f(x)= 1.0901875613260756
# differential_evolution step 413: f(x)= 1.0901875613260756
# differential_evolution step 414: f(x)= 1.0901875613260756
# differential_evolution step 415: f(x)= 1.0901875613260756
# differential_evolution step 416: f(x)= 1.0901875613260756
# differential_evolution step 417: f(x)= 1.0901875613260756
# differential_evolution step 418: f(x)= 1.0901875613260756
# differential_evolution step 419: f(x)= 1.0901875613260756
# differential_evolution step 420: f(x)= 1.0901875613260756
# differential_evolution step 421: f(x)= 1.0901875613260756
# differential_evolution step 422: f(x)= 1.0901875613260756
# differential_evolution step 423: f(x)= 1.0901875613260756
# differential_evolution step 424: f(x)= 1.0901875613260756
# differential_evolution step 425: f(x)= 1.0901875613260756
# differential_evolution step 426: f(x)= 1.0901875613260756
# differential_evolution step 427: f(x)= 1.0901875613260756
# differential_evolution step 428: f(x)= 1.0613776309978373
# differential_evolution step 429: f(x)= 1.0613776309978373
# differential_evolution step 430: f(x)= 1.0613776309978373
# differential_evolution step 431: f(x)= 1.0613776309978373
# differential_evolution step 432: f(x)= 1.0613776309978373
# differential_evolution step 433: f(x)= 1.0613776309978373
# differential_evolution step 434: f(x)= 1.0613776309978373
# differential_evolution step 435: f(x)= 1.0613776309978373
# differential_evolution step 436: f(x)= 1.0613776309978373
# differential_evolution step 437: f(x)= 1.0613776309978373
# differential_evolution step 438: f(x)= 1.0518124022067812
# differential_evolution step 439: f(x)= 1.0518124022067812
# differential_evolution step 440: f(x)= 1.0518124022067812
# differential_evolution step 441: f(x)= 1.0518124022067812
# differential_evolution step 442: f(x)= 1.0518124022067812
# differential_evolution step 443: f(x)= 1.0518124022067812
# differential_evolution step 444: f(x)= 1.0518124022067812
# differential_evolution step 445: f(x)= 1.0388221246423424
# differential_evolution step 446: f(x)= 1.0388221246423424
# differential_evolution step 447: f(x)= 1.0388221246423424
# differential_evolution step 448: f(x)= 0.9951058840253959
# differential_evolution step 449: f(x)= 0.9951058840253959
# differential_evolution step 450: f(x)= 0.9951058840253959
# differential_evolution step 451: f(x)= 0.9951058840253959
# differential_evolution step 452: f(x)= 0.9951058840253959
# differential_evolution step 453: f(x)= 0.9951058840253959
# differential_evolution step 454: f(x)= 0.9951058840253959
# differential_evolution step 455: f(x)= 0.9951058840253959
# differential_evolution step 456: f(x)= 0.9951058840253959
# differential_evolution step 457: f(x)= 0.9951058840253959
# differential_evolution step 458: f(x)= 0.9951058840253959
# differential_evolution step 459: f(x)= 0.9951058840253959
# differential_evolution step 460: f(x)= 0.9951058840253959
# differential_evolution step 461: f(x)= 0.9951058840253959
# differential_evolution step 462: f(x)= 0.9951058840253959
# differential_evolution step 463: f(x)= 0.9951058840253959
# differential_evolution step 464: f(x)= 0.9951058840253959
# differential_evolution step 465: f(x)= 0.9951058840253959
# differential_evolution step 466: f(x)= 0.9951058840253959
# differential_evolution step 467: f(x)= 0.9951058840253959
# differential_evolution step 468: f(x)= 0.9951058840253959
# differential_evolution step 469: f(x)= 0.9951058840253959
# differential_evolution step 470: f(x)= 0.9951058840253959
# differential_evolution step 471: f(x)= 0.9870315575217303
# differential_evolution step 472: f(x)= 0.9870315575217303
# differential_evolution step 473: f(x)= 0.9870315575217303
# differential_evolution step 474: f(x)= 0.9870315575217303
# differential_evolution step 475: f(x)= 0.9870315575217303
# differential_evolution step 476: f(x)= 0.9870315575217303
# differential_evolution step 477: f(x)= 0.9870315575217303
# differential_evolution step 478: f(x)= 0.9870315575217303
# differential_evolution step 479: f(x)= 0.9870315575217303
# differential_evolution step 480: f(x)= 0.9870315575217303
# differential_evolution step 481: f(x)= 0.9870315575217303
# differential_evolution step 482: f(x)= 0.9870315575217303
# differential_evolution step 483: f(x)= 0.9870315575217303
# differential_evolution step 484: f(x)= 0.9870315575217303
# differential_evolution step 485: f(x)= 0.9870315575217303
# differential_evolution step 486: f(x)= 0.9870315575217303
# differential_evolution step 487: f(x)= 0.9870315575217303
# differential_evolution step 488: f(x)= 0.9870315575217303
# differential_evolution step 489: f(x)= 0.9870315575217303
# differential_evolution step 490: f(x)= 0.9870315575217303
# differential_evolution step 491: f(x)= 0.9870315575217303
# differential_evolution step 492: f(x)= 0.9870315575217303
# differential_evolution step 493: f(x)= 0.9870315575217303
# differential_evolution step 494: f(x)= 0.9870315575217303
# differential_evolution step 495: f(x)= 0.9870315575217303
# differential_evolution step 496: f(x)= 0.9870315575217303
# differential_evolution step 497: f(x)= 0.9870315575217303
# differential_evolution step 498: f(x)= 0.9870315575217303
# differential_evolution step 499: f(x)= 0.9870315575217303
# differential_evolution step 500: f(x)= 0.9870315575217303
# differential_evolution step 501: f(x)= 0.9870315575217303
# differential_evolution step 502: f(x)= 0.9870315575217303
# differential_evolution step 503: f(x)= 0.9870315575217303
# differential_evolution step 504: f(x)= 0.9870315575217303
# differential_evolution step 505: f(x)= 0.9870315575217303
# differential_evolution step 506: f(x)= 0.9870315575217303
# differential_evolution step 507: f(x)= 0.9870315575217303
# differential_evolution step 508: f(x)= 0.9870315575217303
# differential_evolution step 509: f(x)= 0.9512786663098457
# differential_evolution step 510: f(x)= 0.9512786663098457
# differential_evolution step 511: f(x)= 0.9512786663098457
# differential_evolution step 512: f(x)= 0.9512786663098457
# differential_evolution step 513: f(x)= 0.9512786663098457
# differential_evolution step 514: f(x)= 0.9512786663098457
# differential_evolution step 515: f(x)= 0.9261998296791879
# differential_evolution step 516: f(x)= 0.9261998296791879
# differential_evolution step 517: f(x)= 0.9261998296791879
# differential_evolution step 518: f(x)= 0.9261998296791879
# differential_evolution step 519: f(x)= 0.9261998296791879
# differential_evolution step 520: f(x)= 0.9261998296791879
# differential_evolution step 521: f(x)= 0.9261998296791879
# differential_evolution step 522: f(x)= 0.9261998296791879
# differential_evolution step 523: f(x)= 0.9261998296791879
# differential_evolution step 524: f(x)= 0.9261998296791879
# differential_evolution step 525: f(x)= 0.9261998296791879
# differential_evolution step 526: f(x)= 0.9261998296791879
# differential_evolution step 527: f(x)= 0.9261998296791879
# differential_evolution step 528: f(x)= 0.9261998296791879
# differential_evolution step 529: f(x)= 0.9261998296791879
# differential_evolution step 530: f(x)= 0.9261998296791879
# differential_evolution step 531: f(x)= 0.9261998296791879
# differential_evolution step 532: f(x)= 0.9261998296791879
# differential_evolution step 533: f(x)= 0.9261998296791879
# differential_evolution step 534: f(x)= 0.9261998296791879
# differential_evolution step 535: f(x)= 0.9261998296791879
# differential_evolution step 536: f(x)= 0.9261998296791879
# differential_evolution step 537: f(x)= 0.9261998296791879
# differential_evolution step 538: f(x)= 0.9261998296791879
# differential_evolution step 539: f(x)= 0.9261998296791879
# differential_evolution step 540: f(x)= 0.9261998296791879
# differential_evolution step 541: f(x)= 0.9261998296791879
# differential_evolution step 542: f(x)= 0.9261998296791879
# differential_evolution step 543: f(x)= 0.9261998296791879
# differential_evolution step 544: f(x)= 0.9261998296791879
# differential_evolution step 545: f(x)= 0.9261998296791879
# differential_evolution step 546: f(x)= 0.9181503194662539
# differential_evolution step 547: f(x)= 0.9181503194662539
# differential_evolution step 548: f(x)= 0.9181503194662539
# differential_evolution step 549: f(x)= 0.9181503194662539
# differential_evolution step 550: f(x)= 0.9181503194662539
# differential_evolution step 551: f(x)= 0.9181503194662539
# differential_evolution step 552: f(x)= 0.9181503194662539
# differential_evolution step 553: f(x)= 0.9181503194662539
# differential_evolution step 554: f(x)= 0.9181503194662539
# differential_evolution step 555: f(x)= 0.9155010900995142
# differential_evolution step 556: f(x)= 0.9155010900995142
# differential_evolution step 557: f(x)= 0.9155010900995142
# differential_evolution step 558: f(x)= 0.9155010900995142
# differential_evolution step 559: f(x)= 0.9155010900995142
# differential_evolution step 560: f(x)= 0.9155010900995142
# differential_evolution step 561: f(x)= 0.9155010900995142
# differential_evolution step 562: f(x)= 0.9155010900995142
# differential_evolution step 563: f(x)= 0.9155010900995142
# differential_evolution step 564: f(x)= 0.9155010900995142
# differential_evolution step 565: f(x)= 0.9155010900995142
# differential_evolution step 566: f(x)= 0.9155010900995142
# differential_evolution step 567: f(x)= 0.9155010900995142
# differential_evolution step 568: f(x)= 0.9155010900995142
# differential_evolution step 569: f(x)= 0.9155010900995142
# differential_evolution step 570: f(x)= 0.9155010900995142
# differential_evolution step 571: f(x)= 0.9155010900995142
# differential_evolution step 572: f(x)= 0.9155010900995142
# differential_evolution step 573: f(x)= 0.9155010900995142
# differential_evolution step 574: f(x)= 0.9155010900995142
# differential_evolution step 575: f(x)= 0.9155010900995142
# differential_evolution step 576: f(x)= 0.9155010900995142
# differential_evolution step 577: f(x)= 0.9155010900995142
# differential_evolution step 578: f(x)= 0.9155010900995142
# differential_evolution step 579: f(x)= 0.9155010900995142
# differential_evolution step 580: f(x)= 0.9155010900995142
# differential_evolution step 581: f(x)= 0.9155010900995142
# differential_evolution step 582: f(x)= 0.9155010900995142
# differential_evolution step 583: f(x)= 0.9155010900995142
# differential_evolution step 584: f(x)= 0.9155010900995142
# differential_evolution step 585: f(x)= 0.9155010900995142
# differential_evolution step 586: f(x)= 0.9155010900995142
# differential_evolution step 587: f(x)= 0.9155010900995142
# differential_evolution step 588: f(x)= 0.9155010900995142
# differential_evolution step 589: f(x)= 0.9155010900995142
# differential_evolution step 590: f(x)= 0.9155010900995142
# differential_evolution step 591: f(x)= 0.9155010900995142
# differential_evolution step 592: f(x)= 0.9155010900995142
# differential_evolution step 593: f(x)= 0.9155010900995142
# differential_evolution step 594: f(x)= 0.9155010900995142
# differential_evolution step 595: f(x)= 0.9155010900995142
# differential_evolution step 596: f(x)= 0.9155010900995142
# differential_evolution step 597: f(x)= 0.9155010900995142
# differential_evolution step 598: f(x)= 0.9155010900995142
# differential_evolution step 599: f(x)= 0.9155010900995142
# differential_evolution step 600: f(x)= 0.9155010900995142
# differential_evolution step 601: f(x)= 0.9155010900995142
# differential_evolution step 602: f(x)= 0.9155010900995142
# differential_evolution step 603: f(x)= 0.9155010900995142
# differential_evolution step 604: f(x)= 0.9155010900995142
# differential_evolution step 605: f(x)= 0.896125749936199
# differential_evolution step 606: f(x)= 0.896125749936199
# differential_evolution step 607: f(x)= 0.896125749936199
# differential_evolution step 608: f(x)= 0.896125749936199
# differential_evolution step 609: f(x)= 0.896125749936199
# differential_evolution step 610: f(x)= 0.896125749936199
# differential_evolution step 611: f(x)= 0.896125749936199
# differential_evolution step 612: f(x)= 0.896125749936199
# differential_evolution step 613: f(x)= 0.896125749936199
# differential_evolution step 614: f(x)= 0.896125749936199
# differential_evolution step 615: f(x)= 0.896125749936199
# differential_evolution step 616: f(x)= 0.896125749936199
# differential_evolution step 617: f(x)= 0.896125749936199
# differential_evolution step 618: f(x)= 0.896125749936199
# differential_evolution step 619: f(x)= 0.896125749936199
# differential_evolution step 620: f(x)= 0.896125749936199
# differential_evolution step 621: f(x)= 0.896125749936199
# differential_evolution step 622: f(x)= 0.896125749936199
# differential_evolution step 623: f(x)= 0.896125749936199
# differential_evolution step 624: f(x)= 0.896125749936199
# differential_evolution step 625: f(x)= 0.896125749936199
# differential_evolution step 626: f(x)= 0.896125749936199
# differential_evolution step 627: f(x)= 0.896125749936199
# differential_evolution step 628: f(x)= 0.896125749936199
# differential_evolution step 629: f(x)= 0.896125749936199
# differential_evolution step 630: f(x)= 0.8784001673464052
# differential_evolution step 631: f(x)= 0.8784001673464052
# differential_evolution step 632: f(x)= 0.8784001673464052
# differential_evolution step 633: f(x)= 0.8784001673464052
# differential_evolution step 634: f(x)= 0.8784001673464052
# differential_evolution step 635: f(x)= 0.8784001673464052
# differential_evolution step 636: f(x)= 0.8784001673464052
# differential_evolution step 637: f(x)= 0.8784001673464052
# differential_evolution step 638: f(x)= 0.8784001673464052
# differential_evolution step 639: f(x)= 0.8784001673464052
# differential_evolution step 640: f(x)= 0.8784001673464052
# differential_evolution step 641: f(x)= 0.8784001673464052
# differential_evolution step 642: f(x)= 0.8784001673464052
# differential_evolution step 643: f(x)= 0.8784001673464052
# differential_evolution step 644: f(x)= 0.8784001673464052
# differential_evolution step 645: f(x)= 0.8784001673464052
# differential_evolution step 646: f(x)= 0.8784001673464052
# differential_evolution step 647: f(x)= 0.8784001673464052
# differential_evolution step 648: f(x)= 0.8784001673464052
# differential_evolution step 649: f(x)= 0.8784001673464052
# differential_evolution step 650: f(x)= 0.8784001673464052
# differential_evolution step 651: f(x)= 0.8784001673464052
# differential_evolution step 652: f(x)= 0.8784001673464052
# differential_evolution step 653: f(x)= 0.8784001673464052
# differential_evolution step 654: f(x)= 0.8784001673464052
# differential_evolution step 655: f(x)= 0.8784001673464052
# differential_evolution step 656: f(x)= 0.8784001673464052
# differential_evolution step 657: f(x)= 0.8784001673464052
# differential_evolution step 658: f(x)= 0.8784001673464052
# differential_evolution step 659: f(x)= 0.8784001673464052
# differential_evolution step 660: f(x)= 0.8784001673464052
# differential_evolution step 661: f(x)= 0.8784001673464052
# differential_evolution step 662: f(x)= 0.8784001673464052
# differential_evolution step 663: f(x)= 0.8784001673464052
# differential_evolution step 664: f(x)= 0.8784001673464052
# differential_evolution step 665: f(x)= 0.8784001673464052
# differential_evolution step 666: f(x)= 0.8784001673464052
# differential_evolution step 667: f(x)= 0.8784001673464052
# differential_evolution step 668: f(x)= 0.8784001673464052
# differential_evolution step 669: f(x)= 0.8784001673464052
# differential_evolution step 670: f(x)= 0.8784001673464052
# differential_evolution step 671: f(x)= 0.8784001673464052
# differential_evolution step 672: f(x)= 0.8784001673464052
# differential_evolution step 673: f(x)= 0.8784001673464052
# differential_evolution step 674: f(x)= 0.8784001673464052
# differential_evolution step 675: f(x)= 0.8784001673464052
# differential_evolution step 676: f(x)= 0.8784001673464052
# differential_evolution step 677: f(x)= 0.8784001673464052
# differential_evolution step 678: f(x)= 0.8784001673464052
# differential_evolution step 679: f(x)= 0.8784001673464052
# differential_evolution step 680: f(x)= 0.8784001673464052
# differential_evolution step 681: f(x)= 0.8784001673464052
# differential_evolution step 682: f(x)= 0.8784001673464052
# differential_evolution step 683: f(x)= 0.8784001673464052
# differential_evolution step 684: f(x)= 0.8784001673464052
# differential_evolution step 685: f(x)= 0.8784001673464052
# differential_evolution step 686: f(x)= 0.8784001673464052
# differential_evolution step 687: f(x)= 0.8784001673464052
# differential_evolution step 688: f(x)= 0.8784001673464052
# differential_evolution step 689: f(x)= 0.8784001673464052
# differential_evolution step 690: f(x)= 0.8784001673464052
# differential_evolution step 691: f(x)= 0.8784001673464052
# differential_evolution step 692: f(x)= 0.8784001673464052
# differential_evolution step 693: f(x)= 0.8784001673464052
# differential_evolution step 694: f(x)= 0.8784001673464052
# differential_evolution step 695: f(x)= 0.8784001673464052
# differential_evolution step 696: f(x)= 0.8703410481260792
# differential_evolution step 697: f(x)= 0.8537912215891408
# differential_evolution step 698: f(x)= 0.8537912215891408
# differential_evolution step 699: f(x)= 0.8537912215891408
# differential_evolution step 700: f(x)= 0.8537912215891408
# differential_evolution step 701: f(x)= 0.8537912215891408
# differential_evolution step 702: f(x)= 0.8512462592215705
# differential_evolution step 703: f(x)= 0.8512462592215705
# differential_evolution step 704: f(x)= 0.8512462592215705
# differential_evolution step 705: f(x)= 0.8512462592215705
# differential_evolution step 706: f(x)= 0.8512462592215705
# differential_evolution step 707: f(x)= 0.8512462592215705
# differential_evolution step 708: f(x)= 0.8512462592215705
# differential_evolution step 709: f(x)= 0.8512462592215705
# differential_evolution step 710: f(x)= 0.8512462592215705
# differential_evolution step 711: f(x)= 0.8512462592215705
# differential_evolution step 712: f(x)= 0.8512462592215705
# differential_evolution step 713: f(x)= 0.8512462592215705
# differential_evolution step 714: f(x)= 0.8512462592215705
# differential_evolution step 715: f(x)= 0.8512462592215705
# differential_evolution step 716: f(x)= 0.8512462592215705
# differential_evolution step 717: f(x)= 0.8512462592215705
# differential_evolution step 718: f(x)= 0.8512462592215705
# differential_evolution step 719: f(x)= 0.8512462592215705
# differential_evolution step 720: f(x)= 0.8512462592215705
# differential_evolution step 721: f(x)= 0.8512462592215705
# differential_evolution step 722: f(x)= 0.8512462592215705
# differential_evolution step 723: f(x)= 0.8512462592215705
# differential_evolution step 724: f(x)= 0.8512462592215705
# differential_evolution step 725: f(x)= 0.8512462592215705
# differential_evolution step 726: f(x)= 0.8512462592215705
# differential_evolution step 727: f(x)= 0.8512462592215705
# differential_evolution step 728: f(x)= 0.8512462592215705
# differential_evolution step 729: f(x)= 0.8512462592215705
# differential_evolution step 730: f(x)= 0.8512462592215705
# differential_evolution step 731: f(x)= 0.8512462592215705
# differential_evolution step 732: f(x)= 0.8512462592215705
# differential_evolution step 733: f(x)= 0.8512462592215705
# differential_evolution step 734: f(x)= 0.8512462592215705
# differential_evolution step 735: f(x)= 0.8512462592215705
# differential_evolution step 736: f(x)= 0.8512462592215705
# differential_evolution step 737: f(x)= 0.8512462592215705
# differential_evolution step 738: f(x)= 0.8512462592215705
# differential_evolution step 739: f(x)= 0.8512462592215705
# differential_evolution step 740: f(x)= 0.8512462592215705
# differential_evolution step 741: f(x)= 0.8512462592215705
# differential_evolution step 742: f(x)= 0.8512462592215705
# differential_evolution step 743: f(x)= 0.8512462592215705
# differential_evolution step 744: f(x)= 0.8512462592215705
# differential_evolution step 745: f(x)= 0.8512462592215705
# differential_evolution step 746: f(x)= 0.8512462592215705
# differential_evolution step 747: f(x)= 0.8512462592215705
# differential_evolution step 748: f(x)= 0.8512462592215705
# differential_evolution step 749: f(x)= 0.8512462592215705
# differential_evolution step 750: f(x)= 0.8512462592215705
# differential_evolution step 751: f(x)= 0.8512462592215705
# differential_evolution step 752: f(x)= 0.8464411548596161
# differential_evolution step 753: f(x)= 0.8464411548596161
# differential_evolution step 754: f(x)= 0.8464411548596161
# differential_evolution step 755: f(x)= 0.8464411548596161
# differential_evolution step 756: f(x)= 0.8464411548596161
# differential_evolution step 757: f(x)= 0.8464411548596161
# differential_evolution step 758: f(x)= 0.8464411548596161
# differential_evolution step 759: f(x)= 0.8464411548596161
# differential_evolution step 760: f(x)= 0.8464411548596161
# differential_evolution step 761: f(x)= 0.8464411548596161
# differential_evolution step 762: f(x)= 0.8464411548596161
# differential_evolution step 763: f(x)= 0.8464411548596161
# differential_evolution step 764: f(x)= 0.8464411548596161
# differential_evolution step 765: f(x)= 0.8464411548596161
# differential_evolution step 766: f(x)= 0.8464411548596161
# differential_evolution step 767: f(x)= 0.8464411548596161
# differential_evolution step 768: f(x)= 0.8464411548596161
# differential_evolution step 769: f(x)= 0.8464411548596161
# differential_evolution step 770: f(x)= 0.8464411548596161
# differential_evolution step 771: f(x)= 0.8464411548596161
# differential_evolution step 772: f(x)= 0.8464411548596161
# differential_evolution step 773: f(x)= 0.8464411548596161
# differential_evolution step 774: f(x)= 0.8464411548596161
# differential_evolution step 775: f(x)= 0.8464411548596161
# differential_evolution step 776: f(x)= 0.8464411548596161
# differential_evolution step 777: f(x)= 0.8464411548596161
# differential_evolution step 778: f(x)= 0.8464411548596161
# differential_evolution step 779: f(x)= 0.8464411548596161
# differential_evolution step 780: f(x)= 0.8464411548596161
# differential_evolution step 781: f(x)= 0.8464411548596161
# differential_evolution step 782: f(x)= 0.8464411548596161
# differential_evolution step 783: f(x)= 0.8464411548596161
# differential_evolution step 784: f(x)= 0.8446046252265726
# differential_evolution step 785: f(x)= 0.8446046252265726
# differential_evolution step 786: f(x)= 0.8446046252265726
# differential_evolution step 787: f(x)= 0.8446046252265726
# differential_evolution step 788: f(x)= 0.8446046252265726
# differential_evolution step 789: f(x)= 0.8446046252265726
# differential_evolution step 790: f(x)= 0.8446046252265726
# differential_evolution step 791: f(x)= 0.8446046252265726
# differential_evolution step 792: f(x)= 0.8446046252265726
# differential_evolution step 793: f(x)= 0.8446046252265726
# differential_evolution step 794: f(x)= 0.8446046252265726
# differential_evolution step 795: f(x)= 0.8446046252265726
# differential_evolution step 796: f(x)= 0.8446046252265726
# differential_evolution step 797: f(x)= 0.8446046252265726
# differential_evolution step 798: f(x)= 0.8446046252265726
# differential_evolution step 799: f(x)= 0.8446046252265726
# differential_evolution step 800: f(x)= 0.8446046252265726
# differential_evolution step 801: f(x)= 0.8359796597402853
# differential_evolution step 802: f(x)= 0.8359796597402853
# differential_evolution step 803: f(x)= 0.8359796597402853
# differential_evolution step 804: f(x)= 0.8359796597402853
# differential_evolution step 805: f(x)= 0.8359796597402853
# differential_evolution step 806: f(x)= 0.8359796597402853
# differential_evolution step 807: f(x)= 0.8359796597402853
# differential_evolution step 808: f(x)= 0.8359796597402853
# differential_evolution step 809: f(x)= 0.8359796597402853
# differential_evolution step 810: f(x)= 0.8359796597402853
# differential_evolution step 811: f(x)= 0.8359796597402853
# differential_evolution step 812: f(x)= 0.8359796597402853
# differential_evolution step 813: f(x)= 0.8359796597402853
# differential_evolution step 814: f(x)= 0.8359796597402853
# differential_evolution step 815: f(x)= 0.8359796597402853
# differential_evolution step 816: f(x)= 0.8359796597402853
# differential_evolution step 817: f(x)= 0.8359796597402853
# differential_evolution step 818: f(x)= 0.8359796597402853
# differential_evolution step 819: f(x)= 0.8359796597402853
# differential_evolution step 820: f(x)= 0.8359796597402853
# differential_evolution step 821: f(x)= 0.8359796597402853
# differential_evolution step 822: f(x)= 0.8359796597402853
# differential_evolution step 823: f(x)= 0.8359796597402853
# differential_evolution step 824: f(x)= 0.8359796597402853
# differential_evolution step 825: f(x)= 0.8359796597402853
# differential_evolution step 826: f(x)= 0.8359796597402853
# differential_evolution step 827: f(x)= 0.8359796597402853
# differential_evolution step 828: f(x)= 0.8359796597402853
# differential_evolution step 829: f(x)= 0.8359796597402853
# differential_evolution step 830: f(x)= 0.8359796597402853
# differential_evolution step 831: f(x)= 0.8359796597402853
# differential_evolution step 832: f(x)= 0.8359796597402853
# differential_evolution step 833: f(x)= 0.8359796597402853
# differential_evolution step 834: f(x)= 0.8359796597402853
# differential_evolution step 835: f(x)= 0.8359796597402853
# differential_evolution step 836: f(x)= 0.8359796597402853
# differential_evolution step 837: f(x)= 0.8359796597402853
# differential_evolution step 838: f(x)= 0.8342156549785281
# differential_evolution step 839: f(x)= 0.8342156549785281
# differential_evolution step 840: f(x)= 0.8342156549785281
# differential_evolution step 841: f(x)= 0.8342156549785281
# differential_evolution step 842: f(x)= 0.8342156549785281
# differential_evolution step 843: f(x)= 0.8342156549785281
# differential_evolution step 844: f(x)= 0.8342156549785281
# differential_evolution step 845: f(x)= 0.8342156549785281
# differential_evolution step 846: f(x)= 0.8342156549785281
# differential_evolution step 847: f(x)= 0.8342156549785281
# differential_evolution step 848: f(x)= 0.8342156549785281
# differential_evolution step 849: f(x)= 0.8342156549785281
# differential_evolution step 850: f(x)= 0.8283155791195301
# differential_evolution step 851: f(x)= 0.8283155791195301
# differential_evolution step 852: f(x)= 0.8283155791195301
# differential_evolution step 853: f(x)= 0.8283155791195301
# differential_evolution step 854: f(x)= 0.8283155791195301
# differential_evolution step 855: f(x)= 0.8283155791195301
# differential_evolution step 856: f(x)= 0.8283155791195301
# differential_evolution step 857: f(x)= 0.8283155791195301
# differential_evolution step 858: f(x)= 0.8283155791195301
# differential_evolution step 859: f(x)= 0.8283155791195301
# differential_evolution step 860: f(x)= 0.8283155791195301
# differential_evolution step 861: f(x)= 0.8283155791195301
# differential_evolution step 862: f(x)= 0.8283155791195301
# differential_evolution step 863: f(x)= 0.8283155791195301
# differential_evolution step 864: f(x)= 0.8283155791195301
# differential_evolution step 865: f(x)= 0.8283155791195301
# differential_evolution step 866: f(x)= 0.8283155791195301
# differential_evolution step 867: f(x)= 0.8283155791195301
# differential_evolution step 868: f(x)= 0.8283155791195301
# differential_evolution step 869: f(x)= 0.8283155791195301
# differential_evolution step 870: f(x)= 0.8283155791195301
# differential_evolution step 871: f(x)= 0.8283155791195301
# differential_evolution step 872: f(x)= 0.8283155791195301
# differential_evolution step 873: f(x)= 0.8283155791195301
# differential_evolution step 874: f(x)= 0.8283155791195301
# differential_evolution step 875: f(x)= 0.8283155791195301
# differential_evolution step 876: f(x)= 0.8283155791195301
# differential_evolution step 877: f(x)= 0.8283155791195301
# differential_evolution step 878: f(x)= 0.8283155791195301
# differential_evolution step 879: f(x)= 0.8283155791195301
# differential_evolution step 880: f(x)= 0.8283155791195301
# differential_evolution step 881: f(x)= 0.8283155791195301
# differential_evolution step 882: f(x)= 0.8283155791195301
# differential_evolution step 883: f(x)= 0.8283155791195301
# differential_evolution step 884: f(x)= 0.8283155791195301
# differential_evolution step 885: f(x)= 0.8283155791195301
# differential_evolution step 886: f(x)= 0.8283155791195301
# differential_evolution step 887: f(x)= 0.8283155791195301
# differential_evolution step 888: f(x)= 0.8283155791195301
# differential_evolution step 889: f(x)= 0.8283155791195301
# differential_evolution step 890: f(x)= 0.8283155791195301
# differential_evolution step 891: f(x)= 0.8283155791195301
# differential_evolution step 892: f(x)= 0.8283155791195301
# differential_evolution step 893: f(x)= 0.8283155791195301
# differential_evolution step 894: f(x)= 0.8283155791195301
# differential_evolution step 895: f(x)= 0.8283155791195301
# differential_evolution step 896: f(x)= 0.8283155791195301
# differential_evolution step 897: f(x)= 0.8283155791195301
# differential_evolution step 898: f(x)= 0.8283155791195301
# differential_evolution step 899: f(x)= 0.8283155791195301
# differential_evolution step 900: f(x)= 0.8283155791195301
# differential_evolution step 901: f(x)= 0.8283155791195301
# differential_evolution step 902: f(x)= 0.8283155791195301
# differential_evolution step 903: f(x)= 0.8283155791195301
# differential_evolution step 904: f(x)= 0.8283155791195301
# differential_evolution step 905: f(x)= 0.8283155791195301
# differential_evolution step 906: f(x)= 0.8283155791195301
# differential_evolution step 907: f(x)= 0.8283155791195301
# differential_evolution step 908: f(x)= 0.8283155791195301
# differential_evolution step 909: f(x)= 0.8283155791195301
# differential_evolution step 910: f(x)= 0.8283155791195301
# differential_evolution step 911: f(x)= 0.8283155791195301
# differential_evolution step 912: f(x)= 0.8283155791195301
# differential_evolution step 913: f(x)= 0.8283155791195301
# differential_evolution step 914: f(x)= 0.8283155791195301
# differential_evolution step 915: f(x)= 0.8283155791195301
# differential_evolution step 916: f(x)= 0.8283155791195301
# differential_evolution step 917: f(x)= 0.8283155791195301
# differential_evolution step 918: f(x)= 0.8250723500486309
# differential_evolution step 919: f(x)= 0.8250723500486309
# differential_evolution step 920: f(x)= 0.8250723500486309
# differential_evolution step 921: f(x)= 0.8250723500486309
# differential_evolution step 922: f(x)= 0.8250723500486309
# differential_evolution step 923: f(x)= 0.8250723500486309
# differential_evolution step 924: f(x)= 0.8250723500486309
# differential_evolution step 925: f(x)= 0.8250723500486309
# differential_evolution step 926: f(x)= 0.8250723500486309
# differential_evolution step 927: f(x)= 0.8250723500486309
# differential_evolution step 928: f(x)= 0.8250723500486309
# differential_evolution step 929: f(x)= 0.8250723500486309
# differential_evolution step 930: f(x)= 0.8250723500486309
# differential_evolution step 931: f(x)= 0.8250723500486309
# differential_evolution step 932: f(x)= 0.8250723500486309
# differential_evolution step 933: f(x)= 0.8250723500486309
# differential_evolution step 934: f(x)= 0.8250723500486309
# differential_evolution step 935: f(x)= 0.8250723500486309
# differential_evolution step 936: f(x)= 0.8250723500486309
# differential_evolution step 937: f(x)= 0.8250723500486309
# differential_evolution step 938: f(x)= 0.8250723500486309
# differential_evolution step 939: f(x)= 0.8250723500486309
# differential_evolution step 940: f(x)= 0.8250723500486309
# differential_evolution step 941: f(x)= 0.8250723500486309
# differential_evolution step 942: f(x)= 0.8250723500486309
# differential_evolution step 943: f(x)= 0.8250723500486309
# differential_evolution step 944: f(x)= 0.8250723500486309
# differential_evolution step 945: f(x)= 0.8250723500486309
# differential_evolution step 946: f(x)= 0.8250723500486309
# differential_evolution step 947: f(x)= 0.8250723500486309
# differential_evolution step 948: f(x)= 0.8250723500486309
# differential_evolution step 949: f(x)= 0.8250723500486309
# differential_evolution step 950: f(x)= 0.8250723500486309
# differential_evolution step 951: f(x)= 0.8250723500486309
# differential_evolution step 952: f(x)= 0.8250723500486309
# differential_evolution step 953: f(x)= 0.8250723500486309
# differential_evolution step 954: f(x)= 0.8250723500486309
# differential_evolution step 955: f(x)= 0.8250723500486309
# differential_evolution step 956: f(x)= 0.8250723500486309
# differential_evolution step 957: f(x)= 0.8243057950007263
# differential_evolution step 958: f(x)= 0.8243057950007263
# differential_evolution step 959: f(x)= 0.8243057950007263
# differential_evolution step 960: f(x)= 0.8243057950007263
# differential_evolution step 961: f(x)= 0.8243057950007263
# differential_evolution step 962: f(x)= 0.8243057950007263
# differential_evolution step 963: f(x)= 0.8243057950007263
# differential_evolution step 964: f(x)= 0.823844312670438
# differential_evolution step 965: f(x)= 0.823844312670438
# differential_evolution step 966: f(x)= 0.823844312670438
# differential_evolution step 967: f(x)= 0.823844312670438
# differential_evolution step 968: f(x)= 0.823844312670438
# differential_evolution step 969: f(x)= 0.823844312670438
# differential_evolution step 970: f(x)= 0.823844312670438
# differential_evolution step 971: f(x)= 0.823844312670438
# differential_evolution step 972: f(x)= 0.8229907730865422
# differential_evolution step 973: f(x)= 0.8229907730865422
# differential_evolution step 974: f(x)= 0.8229907730865422
# differential_evolution step 975: f(x)= 0.8229907730865422
# differential_evolution step 976: f(x)= 0.8229907730865422
# differential_evolution step 977: f(x)= 0.8229907730865422
# differential_evolution step 978: f(x)= 0.8166514834674677
# differential_evolution step 979: f(x)= 0.8166514834674677
# differential_evolution step 980: f(x)= 0.8166514834674677
# differential_evolution step 981: f(x)= 0.8166514834674677
# differential_evolution step 982: f(x)= 0.8166514834674677
# differential_evolution step 983: f(x)= 0.8166514834674677
# differential_evolution step 984: f(x)= 0.813517778988246
# differential_evolution step 985: f(x)= 0.813517778988246
# differential_evolution step 986: f(x)= 0.813517778988246
# differential_evolution step 987: f(x)= 0.813517778988246
# differential_evolution step 988: f(x)= 0.813517778988246
# differential_evolution step 989: f(x)= 0.813517778988246
# differential_evolution step 990: f(x)= 0.813517778988246
# differential_evolution step 991: f(x)= 0.813517778988246
# differential_evolution step 992: f(x)= 0.813517778988246
# differential_evolution step 993: f(x)= 0.813517778988246
# differential_evolution step 994: f(x)= 0.813517778988246
# differential_evolution step 995: f(x)= 0.813517778988246
# differential_evolution step 996: f(x)= 0.813517778988246
# differential_evolution step 997: f(x)= 0.813517778988246
# differential_evolution step 998: f(x)= 0.813517778988246
# differential_evolution step 999: f(x)= 0.813517778988246
# differential_evolution step 1000: f(x)= 0.813517778988246
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [2.75498658e+00 1.50490811e+00 1.04013418e+00 3.19591988e+01
#  1.73427667e-02 4.98363085e+01 3.13796265e+00 7.01977994e+01
#  2.37102369e-01 1.80434552e+00 7.64295665e-01 1.56515729e+01
#  1.83537913e-01 1.19837263e+00 9.09502357e-01 2.01137937e+01
#  1.10730429e-01 3.36184246e+01 3.01416281e+00 3.36696226e+01]
# Chi quadro minimo: 0.8106718161053397

# %%
# Plots:
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2656\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_2656\3084691109.py:11: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.8992, r_e=1.8402, n=1.1149, x_0=32.1402
# Sérsic 2: I_e=0.0068, r_e=120.0623, n=3.6971, x_0=70.1978
# Sérsic 3: I_e=0.3076, r_e=1.9105, n=0.5271, x_0=15.5614
# Sérsic 4: I_e=0.2987, r_e=1.6921, n=0.3598, x_0=20.5661
# Sérsic 5: I_e=0.1085, r_e=31.5242, n=2.7561, x_0=34.0823
# [1.35937822e+00 3.57403324e-01 4.05101415e-01 2.83757428e-01
#  1.47681592e-02 1.92687097e+02 1.92241117e+00 7.93519261e-04
#  3.25614395e-01 9.54696916e-01 8.43028931e-01 9.33524735e-01
#  6.16837111e-01 1.70353966e+00 1.58712540e+00 1.12012451e+00
#  6.56441667e-02 1.30817403e+01 6.22187073e-01 3.10334352e-01]
# 37.691456028840875
# 86.17630451368936 37.691456028840875 133.4412908844818 20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
   (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (68, 73),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (19, 22),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 58081.47720045049
# differential_evolution step 2: f(x)= 20409.578676587247
# differential_evolution step 3: f(x)= 20409.578676587247
# differential_evolution step 4: f(x)= 20409.578676587247
# differential_evolution step 5: f(x)= 20409.578676587247
# differential_evolution step 6: f(x)= 20409.578676587247
# differential_evolution step 7: f(x)= 20409.578676587247
# differential_evolution step 8: f(x)= 20409.578676587247
# differential_evolution step 9: f(x)= 7984.818183890253
# differential_evolution step 10: f(x)= 7984.818183890253
# differential_evolution step 11: f(x)= 7818.730278229177
# differential_evolution step 12: f(x)= 7780.799466681755
# differential_evolution step 13: f(x)= 2478.1137114007333
# differential_evolution step 14: f(x)= 2478.1137114007333
# differential_evolution step 15: f(x)= 2478.1137114007333
# differential_evolution step 16: f(x)= 2478.1137114007333
# differential_evolution step 17: f(x)= 2478.1137114007333
# differential_evolution step 18: f(x)= 2423.5777760422948
# differential_evolution step 19: f(x)= 2423.5777760422948
# differential_evolution step 20: f(x)= 1866.9827177808318
# differential_evolution step 21: f(x)= 1866.9827177808318
# differential_evolution step 22: f(x)= 1866.9827177808318
# differential_evolution step 23: f(x)= 1866.9827177808318
# differential_evolution step 24: f(x)= 1866.9827177808318
# differential_evolution step 25: f(x)= 1866.9827177808318
# differential_evolution step 26: f(x)= 1866.9827177808318
# differential_evolution step 27: f(x)= 1866.9827177808318
# differential_evolution step 28: f(x)= 915.0006797879763
# differential_evolution step 29: f(x)= 915.0006797879763
# differential_evolution step 30: f(x)= 915.0006797879763
# differential_evolution step 31: f(x)= 915.0006797879763
# differential_evolution step 32: f(x)= 915.0006797879763
# differential_evolution step 33: f(x)= 915.0006797879763
# differential_evolution step 34: f(x)= 915.0006797879763
# differential_evolution step 35: f(x)= 915.0006797879763
# differential_evolution step 36: f(x)= 915.0006797879763
# differential_evolution step 37: f(x)= 915.0006797879763
# differential_evolution step 38: f(x)= 915.0006797879763
# differential_evolution step 39: f(x)= 915.0006797879763
# differential_evolution step 40: f(x)= 915.0006797879763
# differential_evolution step 41: f(x)= 424.0200648963495
# differential_evolution step 42: f(x)= 424.0200648963495
# differential_evolution step 43: f(x)= 424.0200648963495
# differential_evolution step 44: f(x)= 408.8410527486235
# differential_evolution step 45: f(x)= 408.8410527486235
# differential_evolution step 46: f(x)= 408.8410527486235
# differential_evolution step 47: f(x)= 408.8410527486235
# differential_evolution step 48: f(x)= 408.8410527486235
# differential_evolution step 49: f(x)= 408.8410527486235
# differential_evolution step 50: f(x)= 408.8410527486235
# differential_evolution step 51: f(x)= 408.8410527486235
# differential_evolution step 52: f(x)= 408.8410527486235
# differential_evolution step 53: f(x)= 408.8410527486235
# differential_evolution step 54: f(x)= 408.8410527486235
# differential_evolution step 55: f(x)= 408.8410527486235
# differential_evolution step 56: f(x)= 408.8410527486235
# differential_evolution step 57: f(x)= 408.8410527486235
# differential_evolution step 58: f(x)= 408.8410527486235
# differential_evolution step 59: f(x)= 408.8410527486235
# differential_evolution step 60: f(x)= 408.8410527486235
# differential_evolution step 61: f(x)= 275.31762944295275
# differential_evolution step 62: f(x)= 275.31762944295275
# differential_evolution step 63: f(x)= 275.31762944295275
# differential_evolution step 64: f(x)= 122.62696488938295
# differential_evolution step 65: f(x)= 107.66141889276393
# differential_evolution step 66: f(x)= 107.66141889276393
# differential_evolution step 67: f(x)= 107.66141889276393
# differential_evolution step 68: f(x)= 107.66141889276393
# differential_evolution step 69: f(x)= 107.66141889276393
# differential_evolution step 70: f(x)= 107.66141889276393
# differential_evolution step 71: f(x)= 107.66141889276393
# differential_evolution step 72: f(x)= 107.66141889276393
# differential_evolution step 73: f(x)= 107.66141889276393
# differential_evolution step 74: f(x)= 101.54216888475872
# differential_evolution step 75: f(x)= 101.54216888475872
# differential_evolution step 76: f(x)= 101.54216888475872
# differential_evolution step 77: f(x)= 101.54216888475872
# differential_evolution step 78: f(x)= 101.54216888475872
# differential_evolution step 79: f(x)= 101.54216888475872
# differential_evolution step 80: f(x)= 101.54216888475872
# differential_evolution step 81: f(x)= 101.54216888475872
# differential_evolution step 82: f(x)= 101.54216888475872
# differential_evolution step 83: f(x)= 101.54216888475872
# differential_evolution step 84: f(x)= 101.54216888475872
# differential_evolution step 85: f(x)= 101.54216888475872
# differential_evolution step 86: f(x)= 101.54216888475872
# differential_evolution step 87: f(x)= 101.54216888475872
# differential_evolution step 88: f(x)= 101.54216888475872
# differential_evolution step 89: f(x)= 101.54216888475872
# differential_evolution step 90: f(x)= 101.54216888475872
# differential_evolution step 91: f(x)= 101.54216888475872
# differential_evolution step 92: f(x)= 101.54216888475872
# differential_evolution step 93: f(x)= 101.54216888475872
# differential_evolution step 94: f(x)= 101.54216888475872
# differential_evolution step 95: f(x)= 101.54216888475872
# differential_evolution step 96: f(x)= 101.54216888475872
# differential_evolution step 97: f(x)= 101.54216888475872
# differential_evolution step 98: f(x)= 101.54216888475872
# differential_evolution step 99: f(x)= 101.54216888475872
# differential_evolution step 100: f(x)= 81.48392109057326
# differential_evolution step 101: f(x)= 81.48392109057326
# differential_evolution step 102: f(x)= 81.48392109057326
# differential_evolution step 103: f(x)= 81.48392109057326
# differential_evolution step 104: f(x)= 81.48392109057326
# differential_evolution step 105: f(x)= 81.48392109057326
# differential_evolution step 106: f(x)= 81.48392109057326
# differential_evolution step 107: f(x)= 81.48392109057326
# differential_evolution step 108: f(x)= 81.48392109057326
# differential_evolution step 109: f(x)= 81.48392109057326
# differential_evolution step 110: f(x)= 81.48392109057326
# differential_evolution step 111: f(x)= 81.48392109057326
# differential_evolution step 112: f(x)= 81.48392109057326
# differential_evolution step 113: f(x)= 60.00145933030905
# differential_evolution step 114: f(x)= 60.00145933030905
# differential_evolution step 115: f(x)= 60.00145933030905
# differential_evolution step 116: f(x)= 60.00145933030905
# differential_evolution step 117: f(x)= 60.00145933030905
# differential_evolution step 118: f(x)= 60.00145933030905
# differential_evolution step 119: f(x)= 60.00145933030905
# differential_evolution step 120: f(x)= 60.00145933030905
# differential_evolution step 121: f(x)= 60.00145933030905
# differential_evolution step 122: f(x)= 60.00145933030905
# differential_evolution step 123: f(x)= 60.00145933030905
# differential_evolution step 124: f(x)= 60.00145933030905
# differential_evolution step 125: f(x)= 60.00145933030905
# differential_evolution step 126: f(x)= 60.00145933030905
# differential_evolution step 127: f(x)= 60.00145933030905
# differential_evolution step 128: f(x)= 60.00145933030905
# differential_evolution step 129: f(x)= 60.00145933030905
# differential_evolution step 130: f(x)= 60.00145933030905
# differential_evolution step 131: f(x)= 60.00145933030905
# differential_evolution step 132: f(x)= 18.396827512353155
# differential_evolution step 133: f(x)= 18.396827512353155
# differential_evolution step 134: f(x)= 18.396827512353155
# differential_evolution step 135: f(x)= 18.396827512353155
# differential_evolution step 136: f(x)= 18.396827512353155
# differential_evolution step 137: f(x)= 18.396827512353155
# differential_evolution step 138: f(x)= 18.396827512353155
# differential_evolution step 139: f(x)= 18.396827512353155
# differential_evolution step 140: f(x)= 18.396827512353155
# differential_evolution step 141: f(x)= 18.396827512353155
# differential_evolution step 142: f(x)= 18.396827512353155
# differential_evolution step 143: f(x)= 18.396827512353155
# differential_evolution step 144: f(x)= 18.396827512353155
# differential_evolution step 145: f(x)= 18.396827512353155
# differential_evolution step 146: f(x)= 18.396827512353155
# differential_evolution step 147: f(x)= 18.396827512353155
# differential_evolution step 148: f(x)= 18.396827512353155
# differential_evolution step 149: f(x)= 18.396827512353155
# differential_evolution step 150: f(x)= 17.537596536375624
# differential_evolution step 151: f(x)= 17.537596536375624
# differential_evolution step 152: f(x)= 17.537596536375624
# differential_evolution step 153: f(x)= 17.537596536375624
# differential_evolution step 154: f(x)= 17.537596536375624
# differential_evolution step 155: f(x)= 17.537596536375624
# differential_evolution step 156: f(x)= 13.783492391063255
# differential_evolution step 157: f(x)= 13.783492391063255
# differential_evolution step 158: f(x)= 13.783492391063255
# differential_evolution step 159: f(x)= 13.783492391063255
# differential_evolution step 160: f(x)= 13.783492391063255
# differential_evolution step 161: f(x)= 13.25532815999368
# differential_evolution step 162: f(x)= 13.25532815999368
# differential_evolution step 163: f(x)= 7.256914393576019
# differential_evolution step 164: f(x)= 7.256914393576019
# differential_evolution step 165: f(x)= 7.256914393576019
# differential_evolution step 166: f(x)= 7.256914393576019
# differential_evolution step 167: f(x)= 6.989135084444365
# differential_evolution step 168: f(x)= 6.989135084444365
# differential_evolution step 169: f(x)= 6.989135084444365
# differential_evolution step 170: f(x)= 6.989135084444365
# differential_evolution step 171: f(x)= 6.989135084444365
# differential_evolution step 172: f(x)= 6.989135084444365
# differential_evolution step 173: f(x)= 6.989135084444365
# differential_evolution step 174: f(x)= 6.989135084444365
# differential_evolution step 175: f(x)= 6.989135084444365
# differential_evolution step 176: f(x)= 6.989135084444365
# differential_evolution step 177: f(x)= 6.989135084444365
# differential_evolution step 178: f(x)= 6.989135084444365
# differential_evolution step 179: f(x)= 6.989135084444365
# differential_evolution step 180: f(x)= 6.989135084444365
# differential_evolution step 181: f(x)= 6.989135084444365
# differential_evolution step 182: f(x)= 6.989135084444365
# differential_evolution step 183: f(x)= 6.989135084444365
# differential_evolution step 184: f(x)= 6.989135084444365
# differential_evolution step 185: f(x)= 6.989135084444365
# differential_evolution step 186: f(x)= 6.989135084444365
# differential_evolution step 187: f(x)= 6.973883621302462
# differential_evolution step 188: f(x)= 6.973883621302462
# differential_evolution step 189: f(x)= 5.5757856957822804
# differential_evolution step 190: f(x)= 5.5757856957822804
# differential_evolution step 191: f(x)= 5.5757856957822804
# differential_evolution step 192: f(x)= 5.5757856957822804
# differential_evolution step 193: f(x)= 5.5757856957822804
# differential_evolution step 194: f(x)= 5.5757856957822804
# differential_evolution step 195: f(x)= 5.247107904516925
# differential_evolution step 196: f(x)= 5.2420959575179324
# differential_evolution step 197: f(x)= 5.2420959575179324
# differential_evolution step 198: f(x)= 5.2420959575179324
# differential_evolution step 199: f(x)= 5.2420959575179324
# differential_evolution step 200: f(x)= 5.191585262321384
# differential_evolution step 201: f(x)= 4.949453061733801
# differential_evolution step 202: f(x)= 4.949453061733801
# differential_evolution step 203: f(x)= 4.949453061733801
# differential_evolution step 204: f(x)= 4.390325044722034
# differential_evolution step 205: f(x)= 3.5580841978113664
# differential_evolution step 206: f(x)= 3.5580841978113664
# differential_evolution step 207: f(x)= 3.5580841978113664
# differential_evolution step 208: f(x)= 3.5580841978113664
# differential_evolution step 209: f(x)= 3.5580841978113664
# differential_evolution step 210: f(x)= 3.5580841978113664
# differential_evolution step 211: f(x)= 3.5580841978113664
# differential_evolution step 212: f(x)= 3.5580841978113664
# differential_evolution step 213: f(x)= 3.2684303412508244
# differential_evolution step 214: f(x)= 3.2684303412508244
# differential_evolution step 215: f(x)= 3.2684303412508244
# differential_evolution step 216: f(x)= 3.2684303412508244
# differential_evolution step 217: f(x)= 3.2684303412508244
# differential_evolution step 218: f(x)= 3.2684303412508244
# differential_evolution step 219: f(x)= 3.2684303412508244
# differential_evolution step 220: f(x)= 3.2684303412508244
# differential_evolution step 221: f(x)= 3.2684303412508244
# differential_evolution step 222: f(x)= 3.2684303412508244
# differential_evolution step 223: f(x)= 3.2684303412508244
# differential_evolution step 224: f(x)= 3.2684303412508244
# differential_evolution step 225: f(x)= 3.2684303412508244
# differential_evolution step 226: f(x)= 3.2684303412508244
# differential_evolution step 227: f(x)= 3.2684303412508244
# differential_evolution step 228: f(x)= 3.2684303412508244
# differential_evolution step 229: f(x)= 3.2684303412508244
# differential_evolution step 230: f(x)= 3.2684303412508244
# differential_evolution step 231: f(x)= 3.2684303412508244
# differential_evolution step 232: f(x)= 3.2684303412508244
# differential_evolution step 233: f(x)= 3.2684303412508244
# differential_evolution step 234: f(x)= 3.2684303412508244
# differential_evolution step 235: f(x)= 3.2684303412508244
# differential_evolution step 236: f(x)= 3.2684303412508244
# differential_evolution step 237: f(x)= 3.2684303412508244
# differential_evolution step 238: f(x)= 3.2684303412508244
# differential_evolution step 239: f(x)= 3.2684303412508244
# differential_evolution step 240: f(x)= 3.2684303412508244
# differential_evolution step 241: f(x)= 3.2684303412508244
# differential_evolution step 242: f(x)= 3.2684303412508244
# differential_evolution step 243: f(x)= 3.2684303412508244
# differential_evolution step 244: f(x)= 2.67382776107772
# differential_evolution step 245: f(x)= 2.67382776107772
# differential_evolution step 246: f(x)= 2.67382776107772
# differential_evolution step 247: f(x)= 2.67382776107772
# differential_evolution step 248: f(x)= 2.67382776107772
# differential_evolution step 249: f(x)= 2.67382776107772
# differential_evolution step 250: f(x)= 2.67382776107772
# differential_evolution step 251: f(x)= 2.67382776107772
# differential_evolution step 252: f(x)= 2.67382776107772
# differential_evolution step 253: f(x)= 2.67382776107772
# differential_evolution step 254: f(x)= 2.67382776107772
# differential_evolution step 255: f(x)= 2.67382776107772
# differential_evolution step 256: f(x)= 2.67382776107772
# differential_evolution step 257: f(x)= 2.67382776107772
# differential_evolution step 258: f(x)= 2.67382776107772
# differential_evolution step 259: f(x)= 2.67382776107772
# differential_evolution step 260: f(x)= 2.67382776107772
# differential_evolution step 261: f(x)= 2.4457547888748143
# differential_evolution step 262: f(x)= 2.4457547888748143
# differential_evolution step 263: f(x)= 2.4457547888748143
# differential_evolution step 264: f(x)= 2.4457547888748143
# differential_evolution step 265: f(x)= 2.4457547888748143
# differential_evolution step 266: f(x)= 2.4204092234998136
# differential_evolution step 267: f(x)= 2.4204092234998136
# differential_evolution step 268: f(x)= 2.4204092234998136
# differential_evolution step 269: f(x)= 2.4204092234998136
# differential_evolution step 270: f(x)= 2.4204092234998136
# differential_evolution step 271: f(x)= 2.4204092234998136
# differential_evolution step 272: f(x)= 2.4204092234998136
# differential_evolution step 273: f(x)= 2.4204092234998136
# differential_evolution step 274: f(x)= 2.282911388604128
# differential_evolution step 275: f(x)= 2.282911388604128
# differential_evolution step 276: f(x)= 2.282911388604128
# differential_evolution step 277: f(x)= 2.282911388604128
# differential_evolution step 278: f(x)= 2.282911388604128
# differential_evolution step 279: f(x)= 2.282911388604128
# differential_evolution step 280: f(x)= 2.282911388604128
# differential_evolution step 281: f(x)= 2.282911388604128
# differential_evolution step 282: f(x)= 2.282911388604128
# differential_evolution step 283: f(x)= 2.0644606951195446
# differential_evolution step 284: f(x)= 2.0644606951195446
# differential_evolution step 285: f(x)= 2.0644606951195446
# differential_evolution step 286: f(x)= 2.0644606951195446
# differential_evolution step 287: f(x)= 2.0175225870891182
# differential_evolution step 288: f(x)= 2.0175225870891182
# differential_evolution step 289: f(x)= 2.0175225870891182
# differential_evolution step 290: f(x)= 2.0175225870891182
# differential_evolution step 291: f(x)= 2.0175225870891182
# differential_evolution step 292: f(x)= 2.0175225870891182
# differential_evolution step 293: f(x)= 2.0175225870891182
# differential_evolution step 294: f(x)= 2.0175225870891182
# differential_evolution step 295: f(x)= 2.0175225870891182
# differential_evolution step 296: f(x)= 2.0175225870891182
# differential_evolution step 297: f(x)= 2.0175225870891182
# differential_evolution step 298: f(x)= 2.0175225870891182
# differential_evolution step 299: f(x)= 1.8600474289816884
# differential_evolution step 300: f(x)= 1.8600474289816884
# differential_evolution step 301: f(x)= 1.8600474289816884
# differential_evolution step 302: f(x)= 1.8600474289816884
# differential_evolution step 303: f(x)= 1.8600474289816884
# differential_evolution step 304: f(x)= 1.7882827851752863
# differential_evolution step 305: f(x)= 1.7882827851752863
# differential_evolution step 306: f(x)= 1.7882827851752863
# differential_evolution step 307: f(x)= 1.7882827851752863
# differential_evolution step 308: f(x)= 1.7882827851752863
# differential_evolution step 309: f(x)= 1.7882827851752863
# differential_evolution step 310: f(x)= 1.7882827851752863
# differential_evolution step 311: f(x)= 1.7882827851752863
# differential_evolution step 312: f(x)= 1.7882827851752863
# differential_evolution step 313: f(x)= 1.7882827851752863
# differential_evolution step 314: f(x)= 1.7882827851752863
# differential_evolution step 315: f(x)= 1.5537969415961896
# differential_evolution step 316: f(x)= 1.5537969415961896
# differential_evolution step 317: f(x)= 1.5537969415961896
# differential_evolution step 318: f(x)= 1.5537969415961896
# differential_evolution step 319: f(x)= 1.5537969415961896
# differential_evolution step 320: f(x)= 1.5537969415961896
# differential_evolution step 321: f(x)= 1.5537969415961896
# differential_evolution step 322: f(x)= 1.5537969415961896
# differential_evolution step 323: f(x)= 1.5537969415961896
# differential_evolution step 324: f(x)= 1.5537969415961896
# differential_evolution step 325: f(x)= 1.5537969415961896
# differential_evolution step 326: f(x)= 1.5537969415961896
# differential_evolution step 327: f(x)= 1.5537969415961896
# differential_evolution step 328: f(x)= 1.5537969415961896
# differential_evolution step 329: f(x)= 1.5537969415961896
# differential_evolution step 330: f(x)= 1.5537969415961896
# differential_evolution step 331: f(x)= 1.5537969415961896
# differential_evolution step 332: f(x)= 1.5537969415961896
# differential_evolution step 333: f(x)= 1.5537969415961896
# differential_evolution step 334: f(x)= 1.5537969415961896
# differential_evolution step 335: f(x)= 1.5537969415961896
# differential_evolution step 336: f(x)= 1.5537969415961896
# differential_evolution step 337: f(x)= 1.5537969415961896
# differential_evolution step 338: f(x)= 1.5537969415961896
# differential_evolution step 339: f(x)= 1.5537969415961896
# differential_evolution step 340: f(x)= 1.5537969415961896
# differential_evolution step 341: f(x)= 1.544601290212816
# differential_evolution step 342: f(x)= 1.544601290212816
# differential_evolution step 343: f(x)= 1.544601290212816
# differential_evolution step 344: f(x)= 1.544601290212816
# differential_evolution step 345: f(x)= 1.544601290212816
# differential_evolution step 346: f(x)= 1.544601290212816
# differential_evolution step 347: f(x)= 1.544601290212816
# differential_evolution step 348: f(x)= 1.544601290212816
# differential_evolution step 349: f(x)= 1.544601290212816
# differential_evolution step 350: f(x)= 1.544601290212816
# differential_evolution step 351: f(x)= 1.544601290212816
# differential_evolution step 352: f(x)= 1.544601290212816
# differential_evolution step 353: f(x)= 1.2742254511513682
# differential_evolution step 354: f(x)= 1.2742254511513682
# differential_evolution step 355: f(x)= 1.2742254511513682
# differential_evolution step 356: f(x)= 1.2742254511513682
# differential_evolution step 357: f(x)= 1.2742254511513682
# differential_evolution step 358: f(x)= 1.2742254511513682
# differential_evolution step 359: f(x)= 1.2742254511513682
# differential_evolution step 360: f(x)= 1.2742254511513682
# differential_evolution step 361: f(x)= 1.139651981221013
# differential_evolution step 362: f(x)= 1.139651981221013
# differential_evolution step 363: f(x)= 1.139651981221013
# differential_evolution step 364: f(x)= 1.139651981221013
# differential_evolution step 365: f(x)= 1.139651981221013
# differential_evolution step 366: f(x)= 1.139651981221013
# differential_evolution step 367: f(x)= 1.139651981221013
# differential_evolution step 368: f(x)= 1.139651981221013
# differential_evolution step 369: f(x)= 1.139651981221013
# differential_evolution step 370: f(x)= 1.139651981221013
# differential_evolution step 371: f(x)= 1.139651981221013
# differential_evolution step 372: f(x)= 1.139651981221013
# differential_evolution step 373: f(x)= 1.139651981221013
# differential_evolution step 374: f(x)= 1.139651981221013
# differential_evolution step 375: f(x)= 1.139651981221013
# differential_evolution step 376: f(x)= 1.139651981221013
# differential_evolution step 377: f(x)= 1.139651981221013
# differential_evolution step 378: f(x)= 1.139651981221013
# differential_evolution step 379: f(x)= 1.139651981221013
# differential_evolution step 380: f(x)= 1.139651981221013
# differential_evolution step 381: f(x)= 1.139651981221013
# differential_evolution step 382: f(x)= 1.139651981221013
# differential_evolution step 383: f(x)= 1.139651981221013
# differential_evolution step 384: f(x)= 1.139651981221013
# differential_evolution step 385: f(x)= 1.139651981221013
# differential_evolution step 386: f(x)= 1.139651981221013
# differential_evolution step 387: f(x)= 1.139651981221013
# differential_evolution step 388: f(x)= 1.139651981221013
# differential_evolution step 389: f(x)= 1.139651981221013
# differential_evolution step 390: f(x)= 0.9893098758675392
# differential_evolution step 391: f(x)= 0.9893098758675392
# differential_evolution step 392: f(x)= 0.9893098758675392
# differential_evolution step 393: f(x)= 0.9893098758675392
# differential_evolution step 394: f(x)= 0.9893098758675392
# differential_evolution step 395: f(x)= 0.9893098758675392
# differential_evolution step 396: f(x)= 0.9893098758675392
# differential_evolution step 397: f(x)= 0.9893098758675392
# differential_evolution step 398: f(x)= 0.9893098758675392
# differential_evolution step 399: f(x)= 0.9893098758675392
# differential_evolution step 400: f(x)= 0.9893098758675392
# differential_evolution step 401: f(x)= 0.9893098758675392
# differential_evolution step 402: f(x)= 0.9893098758675392
# differential_evolution step 403: f(x)= 0.9893098758675392
# differential_evolution step 404: f(x)= 0.9893098758675392
# differential_evolution step 405: f(x)= 0.9893098758675392
# differential_evolution step 406: f(x)= 0.9893098758675392
# differential_evolution step 407: f(x)= 0.9893098758675392
# differential_evolution step 408: f(x)= 0.9893098758675392
# differential_evolution step 409: f(x)= 0.9893098758675392
# differential_evolution step 410: f(x)= 0.9893098758675392
# differential_evolution step 411: f(x)= 0.9893098758675392
# differential_evolution step 412: f(x)= 0.860239739178229
# differential_evolution step 413: f(x)= 0.860239739178229
# differential_evolution step 414: f(x)= 0.860239739178229
# differential_evolution step 415: f(x)= 0.860239739178229
# differential_evolution step 416: f(x)= 0.860239739178229
# differential_evolution step 417: f(x)= 0.860239739178229
# differential_evolution step 418: f(x)= 0.807037226184034
# differential_evolution step 419: f(x)= 0.807037226184034
# differential_evolution step 420: f(x)= 0.807037226184034
# differential_evolution step 421: f(x)= 0.7523327466693843
# differential_evolution step 422: f(x)= 0.7523327466693843
# differential_evolution step 423: f(x)= 0.7523327466693843
# differential_evolution step 424: f(x)= 0.7523327466693843
# differential_evolution step 425: f(x)= 0.7523327466693843
# differential_evolution step 426: f(x)= 0.7523327466693843
# differential_evolution step 427: f(x)= 0.7523327466693843
# differential_evolution step 428: f(x)= 0.7523327466693843
# differential_evolution step 429: f(x)= 0.7523327466693843
# differential_evolution step 430: f(x)= 0.7523327466693843
# differential_evolution step 431: f(x)= 0.7523327466693843
# differential_evolution step 432: f(x)= 0.7523327466693843
# differential_evolution step 433: f(x)= 0.7523327466693843
# differential_evolution step 434: f(x)= 0.7523327466693843
# differential_evolution step 435: f(x)= 0.7523327466693843
# differential_evolution step 436: f(x)= 0.7523327466693843
# differential_evolution step 437: f(x)= 0.7523327466693843
# differential_evolution step 438: f(x)= 0.7523327466693843
# differential_evolution step 439: f(x)= 0.7523327466693843
# differential_evolution step 440: f(x)= 0.7523327466693843
# differential_evolution step 441: f(x)= 0.7523327466693843
# differential_evolution step 442: f(x)= 0.7523327466693843
# differential_evolution step 443: f(x)= 0.7523327466693843
# differential_evolution step 444: f(x)= 0.7523327466693843
# differential_evolution step 445: f(x)= 0.7523327466693843
# differential_evolution step 446: f(x)= 0.7523327466693843
# differential_evolution step 447: f(x)= 0.7523327466693843
# differential_evolution step 448: f(x)= 0.7523327466693843
# differential_evolution step 449: f(x)= 0.7368271749062978
# differential_evolution step 450: f(x)= 0.7368271749062978
# differential_evolution step 451: f(x)= 0.665736752763346
# differential_evolution step 452: f(x)= 0.665736752763346
# differential_evolution step 453: f(x)= 0.665736752763346
# differential_evolution step 454: f(x)= 0.665736752763346
# differential_evolution step 455: f(x)= 0.665736752763346
# differential_evolution step 456: f(x)= 0.665736752763346
# differential_evolution step 457: f(x)= 0.665736752763346
# differential_evolution step 458: f(x)= 0.665736752763346
# differential_evolution step 459: f(x)= 0.665736752763346
# differential_evolution step 460: f(x)= 0.665736752763346
# differential_evolution step 461: f(x)= 0.665736752763346
# differential_evolution step 462: f(x)= 0.665736752763346
# differential_evolution step 463: f(x)= 0.6604549761825393
# differential_evolution step 464: f(x)= 0.6604549761825393
# differential_evolution step 465: f(x)= 0.6604549761825393
# differential_evolution step 466: f(x)= 0.6604549761825393
# differential_evolution step 467: f(x)= 0.6604549761825393
# differential_evolution step 468: f(x)= 0.5984346418274384
# differential_evolution step 469: f(x)= 0.5984346418274384
# differential_evolution step 470: f(x)= 0.5984346418274384
# differential_evolution step 471: f(x)= 0.5984346418274384
# differential_evolution step 472: f(x)= 0.5984346418274384
# differential_evolution step 473: f(x)= 0.5984346418274384
# differential_evolution step 474: f(x)= 0.5984346418274384
# differential_evolution step 475: f(x)= 0.5984346418274384
# differential_evolution step 476: f(x)= 0.5984346418274384
# differential_evolution step 477: f(x)= 0.5984346418274384
# differential_evolution step 478: f(x)= 0.5922285150991495
# differential_evolution step 479: f(x)= 0.5922285150991495
# differential_evolution step 480: f(x)= 0.5922285150991495
# differential_evolution step 481: f(x)= 0.5922285150991495
# differential_evolution step 482: f(x)= 0.5922285150991495
# differential_evolution step 483: f(x)= 0.5922285150991495
# differential_evolution step 484: f(x)= 0.5922285150991495
# differential_evolution step 485: f(x)= 0.5922285150991495
# differential_evolution step 486: f(x)= 0.5922285150991495
# differential_evolution step 487: f(x)= 0.5922285150991495
# differential_evolution step 488: f(x)= 0.5922285150991495
# differential_evolution step 489: f(x)= 0.5922285150991495
# differential_evolution step 490: f(x)= 0.5922285150991495
# differential_evolution step 491: f(x)= 0.5922285150991495
# differential_evolution step 492: f(x)= 0.5906471021712398
# differential_evolution step 493: f(x)= 0.5906471021712398
# differential_evolution step 494: f(x)= 0.5906471021712398
# differential_evolution step 495: f(x)= 0.5906471021712398
# differential_evolution step 496: f(x)= 0.5906471021712398
# differential_evolution step 497: f(x)= 0.5906471021712398
# differential_evolution step 498: f(x)= 0.5906471021712398
# differential_evolution step 499: f(x)= 0.5906471021712398
# differential_evolution step 500: f(x)= 0.5906471021712398
# differential_evolution step 501: f(x)= 0.5906471021712398
# differential_evolution step 502: f(x)= 0.5906471021712398
# differential_evolution step 503: f(x)= 0.5906471021712398
# differential_evolution step 504: f(x)= 0.5906471021712398
# differential_evolution step 505: f(x)= 0.5906471021712398
# differential_evolution step 506: f(x)= 0.5906471021712398
# differential_evolution step 507: f(x)= 0.5906471021712398
# differential_evolution step 508: f(x)= 0.5906471021712398
# differential_evolution step 509: f(x)= 0.5906471021712398
# differential_evolution step 510: f(x)= 0.5906471021712398
# differential_evolution step 511: f(x)= 0.5906471021712398
# differential_evolution step 512: f(x)= 0.5906471021712398
# differential_evolution step 513: f(x)= 0.5906471021712398
# differential_evolution step 514: f(x)= 0.5789025730356154
# differential_evolution step 515: f(x)= 0.5789025730356154
# differential_evolution step 516: f(x)= 0.5789025730356154
# differential_evolution step 517: f(x)= 0.5789025730356154
# differential_evolution step 518: f(x)= 0.5789025730356154
# differential_evolution step 519: f(x)= 0.5789025730356154
# differential_evolution step 520: f(x)= 0.5789025730356154
# differential_evolution step 521: f(x)= 0.5789025730356154
# differential_evolution step 522: f(x)= 0.5789025730356154
# differential_evolution step 523: f(x)= 0.5789025730356154
# differential_evolution step 524: f(x)= 0.5789025730356154
# differential_evolution step 525: f(x)= 0.5789025730356154
# differential_evolution step 526: f(x)= 0.5789025730356154
# differential_evolution step 527: f(x)= 0.5789025730356154
# differential_evolution step 528: f(x)= 0.5768517300560998
# differential_evolution step 529: f(x)= 0.5768517300560998
# differential_evolution step 530: f(x)= 0.5768517300560998
# differential_evolution step 531: f(x)= 0.5768517300560998
# differential_evolution step 532: f(x)= 0.5768517300560998
# differential_evolution step 533: f(x)= 0.5768517300560998
# differential_evolution step 534: f(x)= 0.5768517300560998
# differential_evolution step 535: f(x)= 0.5768517300560998
# differential_evolution step 536: f(x)= 0.5768517300560998
# differential_evolution step 537: f(x)= 0.5768517300560998
# differential_evolution step 538: f(x)= 0.5768517300560998
# differential_evolution step 539: f(x)= 0.5768517300560998
# differential_evolution step 540: f(x)= 0.5768517300560998
# differential_evolution step 541: f(x)= 0.5768517300560998
# differential_evolution step 542: f(x)= 0.5768517300560998
# differential_evolution step 543: f(x)= 0.5768517300560998
# differential_evolution step 544: f(x)= 0.5768517300560998
# differential_evolution step 545: f(x)= 0.5768517300560998
# differential_evolution step 546: f(x)= 0.5768517300560998
# differential_evolution step 547: f(x)= 0.5762046496945841
# differential_evolution step 548: f(x)= 0.5762046496945841
# differential_evolution step 549: f(x)= 0.5762046496945841
# differential_evolution step 550: f(x)= 0.5762046496945841
# differential_evolution step 551: f(x)= 0.5762046496945841
# differential_evolution step 552: f(x)= 0.5762046496945841
# differential_evolution step 553: f(x)= 0.5762046496945841
# differential_evolution step 554: f(x)= 0.5762046496945841
# differential_evolution step 555: f(x)= 0.5762046496945841
# differential_evolution step 556: f(x)= 0.5762046496945841
# differential_evolution step 557: f(x)= 0.5762046496945841
# differential_evolution step 558: f(x)= 0.5762046496945841
# differential_evolution step 559: f(x)= 0.5762046496945841
# differential_evolution step 560: f(x)= 0.5762046496945841
# differential_evolution step 561: f(x)= 0.5762046496945841
# differential_evolution step 562: f(x)= 0.5762046496945841
# differential_evolution step 563: f(x)= 0.5528717623308853
# differential_evolution step 564: f(x)= 0.537818710287926
# differential_evolution step 565: f(x)= 0.5189348702670159
# differential_evolution step 566: f(x)= 0.5189348702670159
# differential_evolution step 567: f(x)= 0.5189348702670159
# differential_evolution step 568: f(x)= 0.5189348702670159
# differential_evolution step 569: f(x)= 0.5189348702670159
# differential_evolution step 570: f(x)= 0.5189348702670159
# differential_evolution step 571: f(x)= 0.5189348702670159
# differential_evolution step 572: f(x)= 0.5189348702670159
# differential_evolution step 573: f(x)= 0.5189348702670159
# differential_evolution step 574: f(x)= 0.5097213841007753
# differential_evolution step 575: f(x)= 0.5097213841007753
# differential_evolution step 576: f(x)= 0.5097213841007753
# differential_evolution step 577: f(x)= 0.4810948496993017
# differential_evolution step 578: f(x)= 0.4810948496993017
# differential_evolution step 579: f(x)= 0.4810948496993017
# differential_evolution step 580: f(x)= 0.4810948496993017
# differential_evolution step 581: f(x)= 0.4810948496993017
# differential_evolution step 582: f(x)= 0.4810948496993017
# differential_evolution step 583: f(x)= 0.4772563659275365
# differential_evolution step 584: f(x)= 0.4772563659275365
# differential_evolution step 585: f(x)= 0.4772563659275365
# differential_evolution step 586: f(x)= 0.4772563659275365
# differential_evolution step 587: f(x)= 0.4772563659275365
# differential_evolution step 588: f(x)= 0.4772563659275365
# differential_evolution step 589: f(x)= 0.4772563659275365
# differential_evolution step 590: f(x)= 0.4772563659275365
# differential_evolution step 591: f(x)= 0.4772563659275365
# differential_evolution step 592: f(x)= 0.4772563659275365
# differential_evolution step 593: f(x)= 0.4772563659275365
# differential_evolution step 594: f(x)= 0.4772563659275365
# differential_evolution step 595: f(x)= 0.4772563659275365
# differential_evolution step 596: f(x)= 0.4772563659275365
# differential_evolution step 597: f(x)= 0.4772563659275365
# differential_evolution step 598: f(x)= 0.4772563659275365
# differential_evolution step 599: f(x)= 0.4772563659275365
# differential_evolution step 600: f(x)= 0.4772563659275365
# differential_evolution step 601: f(x)= 0.46807701218584463
# differential_evolution step 602: f(x)= 0.46807701218584463
# differential_evolution step 603: f(x)= 0.46807701218584463
# differential_evolution step 604: f(x)= 0.46807701218584463
# differential_evolution step 605: f(x)= 0.46807701218584463
# differential_evolution step 606: f(x)= 0.46807701218584463
# differential_evolution step 607: f(x)= 0.46807701218584463
# differential_evolution step 608: f(x)= 0.46807701218584463
# differential_evolution step 609: f(x)= 0.46807701218584463
# differential_evolution step 610: f(x)= 0.46807701218584463
# differential_evolution step 611: f(x)= 0.46807701218584463
# differential_evolution step 612: f(x)= 0.4480736299298231
# differential_evolution step 613: f(x)= 0.4480736299298231
# differential_evolution step 614: f(x)= 0.4480736299298231
# differential_evolution step 615: f(x)= 0.4480736299298231
# differential_evolution step 616: f(x)= 0.4480736299298231
# differential_evolution step 617: f(x)= 0.4480736299298231
# differential_evolution step 618: f(x)= 0.4480736299298231
# differential_evolution step 619: f(x)= 0.4480736299298231
# differential_evolution step 620: f(x)= 0.4480736299298231
# differential_evolution step 621: f(x)= 0.4480736299298231
# differential_evolution step 622: f(x)= 0.4480736299298231
# differential_evolution step 623: f(x)= 0.4480736299298231
# differential_evolution step 624: f(x)= 0.4480736299298231
# differential_evolution step 625: f(x)= 0.4480736299298231
# differential_evolution step 626: f(x)= 0.4480736299298231
# differential_evolution step 627: f(x)= 0.4480736299298231
# differential_evolution step 628: f(x)= 0.4480736299298231
# differential_evolution step 629: f(x)= 0.44239645144396444
# differential_evolution step 630: f(x)= 0.44239645144396444
# differential_evolution step 631: f(x)= 0.44239645144396444
# differential_evolution step 632: f(x)= 0.44239645144396444
# differential_evolution step 633: f(x)= 0.44239645144396444
# differential_evolution step 634: f(x)= 0.44239645144396444
# differential_evolution step 635: f(x)= 0.44239645144396444
# differential_evolution step 636: f(x)= 0.44239645144396444
# differential_evolution step 637: f(x)= 0.44239645144396444
# differential_evolution step 638: f(x)= 0.44239645144396444
# differential_evolution step 639: f(x)= 0.44239645144396444
# differential_evolution step 640: f(x)= 0.44239645144396444
# differential_evolution step 641: f(x)= 0.44239645144396444
# differential_evolution step 642: f(x)= 0.44239645144396444
# differential_evolution step 643: f(x)= 0.44239645144396444
# differential_evolution step 644: f(x)= 0.44239645144396444
# differential_evolution step 645: f(x)= 0.44239645144396444
# differential_evolution step 646: f(x)= 0.44239645144396444
# differential_evolution step 647: f(x)= 0.44239645144396444
# differential_evolution step 648: f(x)= 0.44239645144396444
# differential_evolution step 649: f(x)= 0.44239645144396444
# differential_evolution step 650: f(x)= 0.44239645144396444
# differential_evolution step 651: f(x)= 0.44239645144396444
# differential_evolution step 652: f(x)= 0.44239645144396444
# differential_evolution step 653: f(x)= 0.44239645144396444
# differential_evolution step 654: f(x)= 0.44239645144396444
# differential_evolution step 655: f(x)= 0.44239645144396444
# differential_evolution step 656: f(x)= 0.44239645144396444
# differential_evolution step 657: f(x)= 0.44239645144396444
# differential_evolution step 658: f(x)= 0.44239645144396444
# differential_evolution step 659: f(x)= 0.435269710378434
# differential_evolution step 660: f(x)= 0.435269710378434
# differential_evolution step 661: f(x)= 0.43236542653803073
# differential_evolution step 662: f(x)= 0.43236542653803073
# differential_evolution step 663: f(x)= 0.43236542653803073
# differential_evolution step 664: f(x)= 0.43236542653803073
# differential_evolution step 665: f(x)= 0.3943155169308945
# differential_evolution step 666: f(x)= 0.3943155169308945
# differential_evolution step 667: f(x)= 0.3943155169308945
# differential_evolution step 668: f(x)= 0.3943155169308945
# differential_evolution step 669: f(x)= 0.3943155169308945
# differential_evolution step 670: f(x)= 0.3943155169308945
# differential_evolution step 671: f(x)= 0.3943155169308945
# differential_evolution step 672: f(x)= 0.3943155169308945
# differential_evolution step 673: f(x)= 0.3943155169308945
# differential_evolution step 674: f(x)= 0.3943155169308945
# differential_evolution step 675: f(x)= 0.3943155169308945
# differential_evolution step 676: f(x)= 0.3892328539154287
# differential_evolution step 677: f(x)= 0.3892328539154287
# differential_evolution step 678: f(x)= 0.3892328539154287
# differential_evolution step 679: f(x)= 0.3892328539154287
# differential_evolution step 680: f(x)= 0.3804262572432958
# differential_evolution step 681: f(x)= 0.3804262572432958
# differential_evolution step 682: f(x)= 0.3804262572432958
# differential_evolution step 683: f(x)= 0.35061182161138704
# differential_evolution step 684: f(x)= 0.35061182161138704
# differential_evolution step 685: f(x)= 0.35061182161138704
# differential_evolution step 686: f(x)= 0.35061182161138704
# differential_evolution step 687: f(x)= 0.35061182161138704
# differential_evolution step 688: f(x)= 0.35061182161138704
# differential_evolution step 689: f(x)= 0.35061182161138704
# differential_evolution step 690: f(x)= 0.35061182161138704
# differential_evolution step 691: f(x)= 0.35061182161138704
# differential_evolution step 692: f(x)= 0.35061182161138704
# differential_evolution step 693: f(x)= 0.35061182161138704
# differential_evolution step 694: f(x)= 0.35061182161138704
# differential_evolution step 695: f(x)= 0.35061182161138704
# differential_evolution step 696: f(x)= 0.35061182161138704
# differential_evolution step 697: f(x)= 0.35061182161138704
# differential_evolution step 698: f(x)= 0.35061182161138704
# differential_evolution step 699: f(x)= 0.35061182161138704
# differential_evolution step 700: f(x)= 0.35061182161138704
# differential_evolution step 701: f(x)= 0.35061182161138704
# differential_evolution step 702: f(x)= 0.35061182161138704
# differential_evolution step 703: f(x)= 0.35061182161138704
# differential_evolution step 704: f(x)= 0.35061182161138704
# differential_evolution step 705: f(x)= 0.35061182161138704
# differential_evolution step 706: f(x)= 0.345980089791009
# differential_evolution step 707: f(x)= 0.345980089791009
# differential_evolution step 708: f(x)= 0.345980089791009
# differential_evolution step 709: f(x)= 0.345980089791009
# differential_evolution step 710: f(x)= 0.345980089791009
# differential_evolution step 711: f(x)= 0.345980089791009
# differential_evolution step 712: f(x)= 0.345980089791009
# differential_evolution step 713: f(x)= 0.345980089791009
# differential_evolution step 714: f(x)= 0.345980089791009
# differential_evolution step 715: f(x)= 0.345980089791009
# differential_evolution step 716: f(x)= 0.345980089791009
# differential_evolution step 717: f(x)= 0.345980089791009
# differential_evolution step 718: f(x)= 0.3398021391036713
# differential_evolution step 719: f(x)= 0.3398021391036713
# differential_evolution step 720: f(x)= 0.3398021391036713
# differential_evolution step 721: f(x)= 0.3398021391036713
# differential_evolution step 722: f(x)= 0.3398021391036713
# differential_evolution step 723: f(x)= 0.3398021391036713
# differential_evolution step 724: f(x)= 0.3398021391036713
# differential_evolution step 725: f(x)= 0.3398021391036713
# differential_evolution step 726: f(x)= 0.3398021391036713
# differential_evolution step 727: f(x)= 0.3398021391036713
# differential_evolution step 728: f(x)= 0.3398021391036713
# differential_evolution step 729: f(x)= 0.3398021391036713
# differential_evolution step 730: f(x)= 0.3398021391036713
# differential_evolution step 731: f(x)= 0.3386499828801721
# differential_evolution step 732: f(x)= 0.3386499828801721
# differential_evolution step 733: f(x)= 0.3386499828801721
# differential_evolution step 734: f(x)= 0.3358901552638974
# differential_evolution step 735: f(x)= 0.3358901552638974
# differential_evolution step 736: f(x)= 0.32841702303065046
# differential_evolution step 737: f(x)= 0.32841702303065046
# differential_evolution step 738: f(x)= 0.32841702303065046
# differential_evolution step 739: f(x)= 0.32841702303065046
# differential_evolution step 740: f(x)= 0.32841702303065046
# differential_evolution step 741: f(x)= 0.32459079855020795
# differential_evolution step 742: f(x)= 0.32459079855020795
# differential_evolution step 743: f(x)= 0.32459079855020795
# differential_evolution step 744: f(x)= 0.32459079855020795
# differential_evolution step 745: f(x)= 0.32459079855020795
# differential_evolution step 746: f(x)= 0.32459079855020795
# differential_evolution step 747: f(x)= 0.321064036402244
# differential_evolution step 748: f(x)= 0.321064036402244
# differential_evolution step 749: f(x)= 0.321064036402244
# differential_evolution step 750: f(x)= 0.321064036402244
# differential_evolution step 751: f(x)= 0.321064036402244
# differential_evolution step 752: f(x)= 0.321064036402244
# differential_evolution step 753: f(x)= 0.321064036402244
# differential_evolution step 754: f(x)= 0.3158525228490155
# differential_evolution step 755: f(x)= 0.3158525228490155
# differential_evolution step 756: f(x)= 0.3158525228490155
# differential_evolution step 757: f(x)= 0.3158525228490155
# differential_evolution step 758: f(x)= 0.3158525228490155
# differential_evolution step 759: f(x)= 0.3158525228490155
# differential_evolution step 760: f(x)= 0.3158525228490155
# differential_evolution step 761: f(x)= 0.3158525228490155
# differential_evolution step 762: f(x)= 0.3158525228490155
# differential_evolution step 763: f(x)= 0.3158525228490155
# differential_evolution step 764: f(x)= 0.30875367989989355
# differential_evolution step 765: f(x)= 0.30875367989989355
# differential_evolution step 766: f(x)= 0.30875367989989355
# differential_evolution step 767: f(x)= 0.30875367989989355
# differential_evolution step 768: f(x)= 0.30875367989989355
# differential_evolution step 769: f(x)= 0.29144580308224244
# differential_evolution step 770: f(x)= 0.29144580308224244
# differential_evolution step 771: f(x)= 0.29144580308224244
# differential_evolution step 772: f(x)= 0.29144580308224244
# differential_evolution step 773: f(x)= 0.29144580308224244
# differential_evolution step 774: f(x)= 0.29144580308224244
# differential_evolution step 775: f(x)= 0.29144580308224244
# differential_evolution step 776: f(x)= 0.29144580308224244
# differential_evolution step 777: f(x)= 0.29144580308224244
# differential_evolution step 778: f(x)= 0.29144580308224244
# differential_evolution step 779: f(x)= 0.29144580308224244
# differential_evolution step 780: f(x)= 0.29144580308224244
# differential_evolution step 781: f(x)= 0.29144580308224244
# differential_evolution step 782: f(x)= 0.29144580308224244
# differential_evolution step 783: f(x)= 0.29144580308224244
# differential_evolution step 784: f(x)= 0.29144580308224244
# differential_evolution step 785: f(x)= 0.29144580308224244
# differential_evolution step 786: f(x)= 0.29144580308224244
# differential_evolution step 787: f(x)= 0.29144580308224244
# differential_evolution step 788: f(x)= 0.29144580308224244
# differential_evolution step 789: f(x)= 0.29144580308224244
# differential_evolution step 790: f(x)= 0.29144580308224244
# differential_evolution step 791: f(x)= 0.29144580308224244
# differential_evolution step 792: f(x)= 0.29144580308224244
# differential_evolution step 793: f(x)= 0.29144580308224244
# differential_evolution step 794: f(x)= 0.29144580308224244
# differential_evolution step 795: f(x)= 0.29144580308224244
# differential_evolution step 796: f(x)= 0.29144580308224244
# differential_evolution step 797: f(x)= 0.29144580308224244
# differential_evolution step 798: f(x)= 0.29144580308224244
# differential_evolution step 799: f(x)= 0.29144580308224244
# differential_evolution step 800: f(x)= 0.29144580308224244
# differential_evolution step 801: f(x)= 0.29144580308224244
# differential_evolution step 802: f(x)= 0.29144580308224244
# differential_evolution step 803: f(x)= 0.29144580308224244
# differential_evolution step 804: f(x)= 0.29144580308224244
# differential_evolution step 805: f(x)= 0.29144580308224244
# differential_evolution step 806: f(x)= 0.29005141902177756
# differential_evolution step 807: f(x)= 0.29005141902177756
# differential_evolution step 808: f(x)= 0.29005141902177756
# differential_evolution step 809: f(x)= 0.29005141902177756
# differential_evolution step 810: f(x)= 0.29005141902177756
# differential_evolution step 811: f(x)= 0.2793080758342984
# differential_evolution step 812: f(x)= 0.2793080758342984
# differential_evolution step 813: f(x)= 0.2793080758342984
# differential_evolution step 814: f(x)= 0.2793080758342984
# differential_evolution step 815: f(x)= 0.2793080758342984
# differential_evolution step 816: f(x)= 0.2793080758342984
# differential_evolution step 817: f(x)= 0.2793080758342984
# differential_evolution step 818: f(x)= 0.2793080758342984
# differential_evolution step 819: f(x)= 0.2793080758342984
# differential_evolution step 820: f(x)= 0.2793080758342984
# differential_evolution step 821: f(x)= 0.2793080758342984
# differential_evolution step 822: f(x)= 0.2793080758342984
# differential_evolution step 823: f(x)= 0.2793080758342984
# differential_evolution step 824: f(x)= 0.27231647922984437
# differential_evolution step 825: f(x)= 0.27231647922984437
# differential_evolution step 826: f(x)= 0.27231647922984437
# differential_evolution step 827: f(x)= 0.27231647922984437
# differential_evolution step 828: f(x)= 0.27231647922984437
# differential_evolution step 829: f(x)= 0.27231647922984437
# differential_evolution step 830: f(x)= 0.27231647922984437
# differential_evolution step 831: f(x)= 0.27231647922984437
# differential_evolution step 832: f(x)= 0.27231647922984437
# differential_evolution step 833: f(x)= 0.27231647922984437
# differential_evolution step 834: f(x)= 0.27231647922984437
# differential_evolution step 835: f(x)= 0.27231647922984437
# differential_evolution step 836: f(x)= 0.27231647922984437
# differential_evolution step 837: f(x)= 0.27231647922984437
# differential_evolution step 838: f(x)= 0.27231647922984437
# differential_evolution step 839: f(x)= 0.27231647922984437
# differential_evolution step 840: f(x)= 0.27231647922984437
# differential_evolution step 841: f(x)= 0.27231647922984437
# differential_evolution step 842: f(x)= 0.27231647922984437
# differential_evolution step 843: f(x)= 0.27231647922984437
# differential_evolution step 844: f(x)= 0.27231647922984437
# differential_evolution step 845: f(x)= 0.27231647922984437
# differential_evolution step 846: f(x)= 0.27231647922984437
# differential_evolution step 847: f(x)= 0.27231647922984437
# differential_evolution step 848: f(x)= 0.27231647922984437
# differential_evolution step 849: f(x)= 0.27231647922984437
# differential_evolution step 850: f(x)= 0.27231647922984437
# differential_evolution step 851: f(x)= 0.27231647922984437
# differential_evolution step 852: f(x)= 0.27231647922984437
# differential_evolution step 853: f(x)= 0.27231647922984437
# differential_evolution step 854: f(x)= 0.27231647922984437
# differential_evolution step 855: f(x)= 0.268640779893092
# differential_evolution step 856: f(x)= 0.268640779893092
# differential_evolution step 857: f(x)= 0.268640779893092
# differential_evolution step 858: f(x)= 0.268640779893092
# differential_evolution step 859: f(x)= 0.268640779893092
# differential_evolution step 860: f(x)= 0.268640779893092
# differential_evolution step 861: f(x)= 0.268640779893092
# differential_evolution step 862: f(x)= 0.268640779893092
# differential_evolution step 863: f(x)= 0.268640779893092
# differential_evolution step 864: f(x)= 0.268640779893092
# differential_evolution step 865: f(x)= 0.268640779893092
# differential_evolution step 866: f(x)= 0.268640779893092
# differential_evolution step 867: f(x)= 0.268640779893092
# differential_evolution step 868: f(x)= 0.268640779893092
# differential_evolution step 869: f(x)= 0.268640779893092
# differential_evolution step 870: f(x)= 0.268640779893092
# differential_evolution step 871: f(x)= 0.268640779893092
# differential_evolution step 872: f(x)= 0.268640779893092
# differential_evolution step 873: f(x)= 0.268640779893092
# differential_evolution step 874: f(x)= 0.268640779893092
# differential_evolution step 875: f(x)= 0.268640779893092
# differential_evolution step 876: f(x)= 0.268640779893092
# differential_evolution step 877: f(x)= 0.268640779893092
# differential_evolution step 878: f(x)= 0.268640779893092
# differential_evolution step 879: f(x)= 0.268640779893092
# differential_evolution step 880: f(x)= 0.268640779893092
# differential_evolution step 881: f(x)= 0.268640779893092
# differential_evolution step 882: f(x)= 0.268640779893092
# differential_evolution step 883: f(x)= 0.268640779893092
# differential_evolution step 884: f(x)= 0.268640779893092
# differential_evolution step 885: f(x)= 0.268640779893092
# differential_evolution step 886: f(x)= 0.268640779893092
# differential_evolution step 887: f(x)= 0.268640779893092
# differential_evolution step 888: f(x)= 0.268640779893092
# differential_evolution step 889: f(x)= 0.268640779893092
# differential_evolution step 890: f(x)= 0.268640779893092
# differential_evolution step 891: f(x)= 0.268640779893092
# differential_evolution step 892: f(x)= 0.268640779893092
# differential_evolution step 893: f(x)= 0.268640779893092
# differential_evolution step 894: f(x)= 0.268640779893092
# differential_evolution step 895: f(x)= 0.268640779893092
# differential_evolution step 896: f(x)= 0.268640779893092
# differential_evolution step 897: f(x)= 0.268640779893092
# differential_evolution step 898: f(x)= 0.265265176233655
# differential_evolution step 899: f(x)= 0.265265176233655
# differential_evolution step 900: f(x)= 0.265265176233655
# differential_evolution step 901: f(x)= 0.265265176233655
# differential_evolution step 902: f(x)= 0.2616921147187168
# differential_evolution step 903: f(x)= 0.2616921147187168
# differential_evolution step 904: f(x)= 0.2616921147187168
# differential_evolution step 905: f(x)= 0.2616921147187168
# differential_evolution step 906: f(x)= 0.2566430975863111
# differential_evolution step 907: f(x)= 0.2566430975863111
# differential_evolution step 908: f(x)= 0.24824022547209665
# differential_evolution step 909: f(x)= 0.24824022547209665
# differential_evolution step 910: f(x)= 0.24824022547209665
# differential_evolution step 911: f(x)= 0.24824022547209665
# differential_evolution step 912: f(x)= 0.24824022547209665
# differential_evolution step 913: f(x)= 0.24824022547209665
# differential_evolution step 914: f(x)= 0.24824022547209665
# differential_evolution step 915: f(x)= 0.24824022547209665
# differential_evolution step 916: f(x)= 0.24824022547209665
# differential_evolution step 917: f(x)= 0.24824022547209665
# differential_evolution step 918: f(x)= 0.24824022547209665
# differential_evolution step 919: f(x)= 0.24824022547209665
# differential_evolution step 920: f(x)= 0.24824022547209665
# differential_evolution step 921: f(x)= 0.24824022547209665
# differential_evolution step 922: f(x)= 0.24824022547209665
# differential_evolution step 923: f(x)= 0.24824022547209665
# differential_evolution step 924: f(x)= 0.24824022547209665
# differential_evolution step 925: f(x)= 0.24824022547209665
# differential_evolution step 926: f(x)= 0.24824022547209665
# differential_evolution step 927: f(x)= 0.24824022547209665
# differential_evolution step 928: f(x)= 0.24824022547209665
# differential_evolution step 929: f(x)= 0.24824022547209665
# differential_evolution step 930: f(x)= 0.24824022547209665
# differential_evolution step 931: f(x)= 0.24824022547209665
# differential_evolution step 932: f(x)= 0.24824022547209665
# differential_evolution step 933: f(x)= 0.24824022547209665
# differential_evolution step 934: f(x)= 0.24824022547209665
# differential_evolution step 935: f(x)= 0.24580580712947736
# differential_evolution step 936: f(x)= 0.24580580712947736
# differential_evolution step 937: f(x)= 0.24580580712947736
# differential_evolution step 938: f(x)= 0.24580580712947736
# differential_evolution step 939: f(x)= 0.24580580712947736
# differential_evolution step 940: f(x)= 0.24580580712947736
# differential_evolution step 941: f(x)= 0.24580580712947736
# differential_evolution step 942: f(x)= 0.24580580712947736
# differential_evolution step 943: f(x)= 0.24580580712947736
# differential_evolution step 944: f(x)= 0.24580580712947736
# differential_evolution step 945: f(x)= 0.24580580712947736
# differential_evolution step 946: f(x)= 0.24580580712947736
# differential_evolution step 947: f(x)= 0.24580580712947736
# differential_evolution step 948: f(x)= 0.24580580712947736
# differential_evolution step 949: f(x)= 0.24580580712947736
# differential_evolution step 950: f(x)= 0.24580580712947736
# differential_evolution step 951: f(x)= 0.24580580712947736
# differential_evolution step 952: f(x)= 0.24580580712947736
# differential_evolution step 953: f(x)= 0.24580580712947736
# differential_evolution step 954: f(x)= 0.24580580712947736
# differential_evolution step 955: f(x)= 0.24580580712947736
# differential_evolution step 956: f(x)= 0.24580580712947736
# differential_evolution step 957: f(x)= 0.24580580712947736
# differential_evolution step 958: f(x)= 0.24580580712947736
# differential_evolution step 959: f(x)= 0.24580580712947736
# differential_evolution step 960: f(x)= 0.24580580712947736
# differential_evolution step 961: f(x)= 0.24580580712947736
# differential_evolution step 962: f(x)= 0.24580580712947736
# differential_evolution step 963: f(x)= 0.24580580712947736
# differential_evolution step 964: f(x)= 0.24580580712947736
# differential_evolution step 965: f(x)= 0.24580580712947736
# differential_evolution step 966: f(x)= 0.24502620520669482
# differential_evolution step 967: f(x)= 0.24502620520669482
# differential_evolution step 968: f(x)= 0.24502620520669482
# differential_evolution step 969: f(x)= 0.24502620520669482
# differential_evolution step 970: f(x)= 0.24502620520669482
# differential_evolution step 971: f(x)= 0.24502620520669482
# differential_evolution step 972: f(x)= 0.24502620520669482
# differential_evolution step 973: f(x)= 0.24502620520669482
# differential_evolution step 974: f(x)= 0.24502620520669482
# differential_evolution step 975: f(x)= 0.24502620520669482
# differential_evolution step 976: f(x)= 0.24502620520669482
# differential_evolution step 977: f(x)= 0.24502620520669482
# differential_evolution step 978: f(x)= 0.24502620520669482
# differential_evolution step 979: f(x)= 0.24502620520669482
# differential_evolution step 980: f(x)= 0.24502620520669482
# differential_evolution step 981: f(x)= 0.24502620520669482
# differential_evolution step 982: f(x)= 0.24502620520669482
# differential_evolution step 983: f(x)= 0.24502620520669482
# differential_evolution step 984: f(x)= 0.24502620520669482
# differential_evolution step 985: f(x)= 0.24502620520669482
# differential_evolution step 986: f(x)= 0.24502620520669482
# differential_evolution step 987: f(x)= 0.24502620520669482
# differential_evolution step 988: f(x)= 0.24502620520669482
# differential_evolution step 989: f(x)= 0.24502620520669482
# differential_evolution step 990: f(x)= 0.24502620520669482
# differential_evolution step 991: f(x)= 0.24502620520669482
# differential_evolution step 992: f(x)= 0.24502620520669482
# differential_evolution step 993: f(x)= 0.24502620520669482
# differential_evolution step 994: f(x)= 0.24502620520669482
# differential_evolution step 995: f(x)= 0.24398856345279127
# differential_evolution step 996: f(x)= 0.24398856345279127
# differential_evolution step 997: f(x)= 0.24398856345279127
# differential_evolution step 998: f(x)= 0.24398856345279127
# differential_evolution step 999: f(x)= 0.24398856345279127
# differential_evolution step 1000: f(x)= 0.24398856345279127
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [4.90021261e+00 2.30733907e+00 7.91039574e-01 3.26532160e+01
#  4.92866445e-01 2.04574136e+00 9.32793917e-01 7.03646281e+01
#  1.62642130e-01 1.74678740e+00 8.02319486e-01 1.53997704e+01
#  2.03661386e-01 8.80067264e+00 8.15777147e-01 2.11475629e+01
#  1.42031019e-01 1.25567797e+01 1.50199693e+00 3.82680670e+01
#  6.71266125e-02 4.95160840e+01 1.19097661e+00 6.27988889e+01]
# Chi quadro minimo: 0.2142223453877456

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=4.5605, r_e=2.3872, n=0.8470, x_0=32.6413
# Sérsic 2: I_e=0.3808, r_e=2.6932, n=1.1102, x_0=70.3139
# Sérsic 3: I_e=0.0979, r_e=2.5495, n=1.1680, x_0=15.1628
# Sérsic 4: I_e=0.2745, r_e=5.7536, n=0.6007, x_0=20.8526
# Sérsic 5: I_e=0.1890, r_e=11.4101, n=1.2842, x_0=38.0598
# Sérsic 6: I_e=0.0049, r_e=600.6334, n=2.7109, x_0=61.7041
# [4.85179138e-01 1.75123778e-01 8.25573630e-02 2.38380897e-02
#  1.14406007e-01 4.80435756e-01 2.47468835e-01 6.07727494e-02
#  3.51901389e-01 8.41690679e+00 2.75107454e+00 3.51342856e-01
#  9.98095586e-02 3.18320608e+00 2.78176593e-01 1.23247928e+00
#  6.55075073e-02 2.70258115e+00 2.18812434e-01 3.42203005e-01
#  5.02275715e-03 6.04062202e+02 5.96445108e-01 3.89222285e-01]
# 8.36875390270214
# 69.00033285007056 8.36875390270214 123.26855572947125 24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
