# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-02-017/MGC+01-02-017_1/FORS2.2021-10-04T04_41_52.988/MCG+01-02-017_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-02-017/MGC+01-02-017_1/FORS2.2021-10-04T04_41_52.988/MCG+01-02-017_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     361   (2094, 963)   float32
#   1  IMAGE.ERR     1 ImageHDU        42   (2094, 963)   float32

# %%
image_cut = image[61:161, 0:1890]
image_error_cut = image_error[61:161, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 20), vmax=np.percentile(image_cut, 95))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.0429
l_HA_z = 6563 * (1+z)
l_HB_z = 4861 * (1+z) 
l_NII_z = 6583 * (1+z)
l_SII_z = 6717 * (1+z)
l_OIII_z = 5007 * (1+z)
#Non combaciano 
l_HA = 6838
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/MGC+01-02-017/PSF/Real_seeing_MCG+01-02-017.txt")
sigma = seeing[0] / 2.35

# %%
l_HA
# Out:
# 6838

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),  # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 10.809658610425137
# differential_evolution step 2: f(x)= 10.809658610425137
# differential_evolution step 3: f(x)= 6.576984860520602
# differential_evolution step 4: f(x)= 6.576984860520602
# differential_evolution step 5: f(x)= 5.605426041001009
# differential_evolution step 6: f(x)= 5.209529762964496
# differential_evolution step 7: f(x)= 5.209529762964496
# differential_evolution step 8: f(x)= 5.209529762964496
# differential_evolution step 9: f(x)= 5.146199753523608
# differential_evolution step 10: f(x)= 5.009785098399206
# differential_evolution step 11: f(x)= 4.830064192325485
# differential_evolution step 12: f(x)= 4.246651611143232
# differential_evolution step 13: f(x)= 4.246651611143232
# differential_evolution step 14: f(x)= 4.246651611143232
# differential_evolution step 15: f(x)= 4.246651611143232
# differential_evolution step 16: f(x)= 4.246651611143232
# differential_evolution step 17: f(x)= 4.246651611143232
# differential_evolution step 18: f(x)= 4.165232776155935
# differential_evolution step 19: f(x)= 4.165232776155935
# differential_evolution step 20: f(x)= 4.165232776155935
# differential_evolution step 21: f(x)= 4.165232776155935
# differential_evolution step 22: f(x)= 4.165232776155935
# differential_evolution step 23: f(x)= 4.139542441743095
# differential_evolution step 24: f(x)= 4.139542441743095
# differential_evolution step 25: f(x)= 4.132759084596372
# differential_evolution step 26: f(x)= 4.115240045116617
# differential_evolution step 27: f(x)= 4.109468648027628
# differential_evolution step 28: f(x)= 4.100909135373431
# differential_evolution step 29: f(x)= 4.100909135373431
# differential_evolution step 30: f(x)= 4.100909135373431
# differential_evolution step 31: f(x)= 4.100909135373431
# differential_evolution step 32: f(x)= 4.099890325731032
# differential_evolution step 33: f(x)= 4.099890325731032
# differential_evolution step 34: f(x)= 4.098579896380619
# differential_evolution step 35: f(x)= 4.098579896380619
# differential_evolution step 36: f(x)= 4.09605393960202
# differential_evolution step 37: f(x)= 4.092369298359592
# differential_evolution step 38: f(x)= 4.091866516152271
# differential_evolution step 39: f(x)= 4.091866516152271
# differential_evolution step 40: f(x)= 4.091866516152271
# differential_evolution step 41: f(x)= 4.091263195838089
# differential_evolution step 42: f(x)= 4.091263195838089
# differential_evolution step 43: f(x)= 4.091263195838089
# differential_evolution step 44: f(x)= 4.090907637978335
# differential_evolution step 45: f(x)= 4.090907637978335
# differential_evolution step 46: f(x)= 4.090907637978335
# differential_evolution step 47: f(x)= 4.09076305625908
# differential_evolution step 48: f(x)= 4.09076305625908
# differential_evolution step 49: f(x)= 4.09076305625908
# differential_evolution step 50: f(x)= 4.09076305625908
# differential_evolution step 51: f(x)= 4.09076305625908
# differential_evolution step 52: f(x)= 4.090759626138188
# differential_evolution step 53: f(x)= 4.090655808417742
# differential_evolution step 54: f(x)= 4.090655808417742
# differential_evolution step 55: f(x)= 4.090655808417742
# differential_evolution step 56: f(x)= 4.090655808417742
# differential_evolution step 57: f(x)= 4.090655808417742
# differential_evolution step 58: f(x)= 4.090655808417742
# differential_evolution step 59: f(x)= 4.0906533690536575
# differential_evolution step 60: f(x)= 4.0906533690536575
# differential_evolution step 61: f(x)= 4.0906533690536575
# differential_evolution step 62: f(x)= 4.0906533690536575
# differential_evolution step 63: f(x)= 4.0906533690536575
# differential_evolution step 64: f(x)= 4.0906533690536575
# differential_evolution step 65: f(x)= 4.090646874633375
# differential_evolution step 66: f(x)= 4.090646874633375
# differential_evolution step 67: f(x)= 4.090646874633375
# differential_evolution step 68: f(x)= 4.090642611255558
# differential_evolution step 69: f(x)= 4.090642611255558
# differential_evolution step 70: f(x)= 4.090642611255558
# differential_evolution step 71: f(x)= 4.090638952870157
# differential_evolution step 72: f(x)= 4.090638952870157
# differential_evolution step 73: f(x)= 4.090638952870157
# differential_evolution step 74: f(x)= 4.090637402638078
# differential_evolution step 75: f(x)= 4.090637402638078
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.14310953 50.          1.35190855 56.5183796 ]
# Chi quadro minimo: 4.090635772892411

# %%
# Plots:
aic = np.zeros(7)
bic = np.zeros(7)
chi_quadr = np.zeros(7)
chi_quadro = np.zeros(7)
red_chi = np.zeros(7)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0116, r_e=410.3031, n=2.9631, x_0=56.3698
# [2.70178937e-02 8.13481080e+02 1.63161649e+00 5.17261165e-03]
# 97.78360974483822
# 106.20466237641716 0.0 116.20429048879058 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 111.31156389289487
# differential_evolution step 2: f(x)= 111.31156389289487
# differential_evolution step 3: f(x)= 102.68151651350873
# differential_evolution step 4: f(x)= 9.979054212301712
# differential_evolution step 5: f(x)= 9.979054212301712
# differential_evolution step 6: f(x)= 4.998036107580242
# differential_evolution step 7: f(x)= 4.998036107580242
# differential_evolution step 8: f(x)= 4.998036107580242
# differential_evolution step 9: f(x)= 4.998036107580242
# differential_evolution step 10: f(x)= 4.998036107580242
# differential_evolution step 11: f(x)= 4.305942378908941
# differential_evolution step 12: f(x)= 4.305942378908941
# differential_evolution step 13: f(x)= 2.666552195315764
# differential_evolution step 14: f(x)= 2.666552195315764
# differential_evolution step 15: f(x)= 2.6059533554008008
# differential_evolution step 16: f(x)= 2.6059533554008008
# differential_evolution step 17: f(x)= 2.178694806472592
# differential_evolution step 18: f(x)= 2.178694806472592
# differential_evolution step 19: f(x)= 2.178694806472592
# differential_evolution step 20: f(x)= 1.9694158297408384
# differential_evolution step 21: f(x)= 1.9694158297408384
# differential_evolution step 22: f(x)= 1.9694158297408384
# differential_evolution step 23: f(x)= 1.9694158297408384
# differential_evolution step 24: f(x)= 1.9694158297408384
# differential_evolution step 25: f(x)= 1.9694158297408384
# differential_evolution step 26: f(x)= 1.9694158297408384
# differential_evolution step 27: f(x)= 1.9694158297408384
# differential_evolution step 28: f(x)= 1.7298438269600669
# differential_evolution step 29: f(x)= 1.7298438269600669
# differential_evolution step 30: f(x)= 1.7298438269600669
# differential_evolution step 31: f(x)= 1.7298438269600669
# differential_evolution step 32: f(x)= 1.5865342590184612
# differential_evolution step 33: f(x)= 1.5865342590184612
# differential_evolution step 34: f(x)= 1.5865342590184612
# differential_evolution step 35: f(x)= 1.5865342590184612
# differential_evolution step 36: f(x)= 1.5506346337679604
# differential_evolution step 37: f(x)= 1.4394077890903476
# differential_evolution step 38: f(x)= 1.3914065125310664
# differential_evolution step 39: f(x)= 1.251544808581441
# differential_evolution step 40: f(x)= 1.251544808581441
# differential_evolution step 41: f(x)= 1.251544808581441
# differential_evolution step 42: f(x)= 1.251544808581441
# differential_evolution step 43: f(x)= 1.251544808581441
# differential_evolution step 44: f(x)= 1.251544808581441
# differential_evolution step 45: f(x)= 1.251544808581441
# differential_evolution step 46: f(x)= 1.251544808581441
# differential_evolution step 47: f(x)= 1.251544808581441
# differential_evolution step 48: f(x)= 1.164981001580149
# differential_evolution step 49: f(x)= 1.164981001580149
# differential_evolution step 50: f(x)= 1.164981001580149
# differential_evolution step 51: f(x)= 1.164981001580149
# differential_evolution step 52: f(x)= 1.164981001580149
# differential_evolution step 53: f(x)= 1.164981001580149
# differential_evolution step 54: f(x)= 1.164981001580149
# differential_evolution step 55: f(x)= 1.164981001580149
# differential_evolution step 56: f(x)= 1.1588833162655547
# differential_evolution step 57: f(x)= 1.1588833162655547
# differential_evolution step 58: f(x)= 1.1425220833045817
# differential_evolution step 59: f(x)= 1.1425220833045817
# differential_evolution step 60: f(x)= 1.1425220833045817
# differential_evolution step 61: f(x)= 1.1398997246132436
# differential_evolution step 62: f(x)= 1.1398997246132436
# differential_evolution step 63: f(x)= 1.1398997246132436
# differential_evolution step 64: f(x)= 1.1398997246132436
# differential_evolution step 65: f(x)= 1.1398997246132436
# differential_evolution step 66: f(x)= 1.1398997246132436
# differential_evolution step 67: f(x)= 1.1398997246132436
# differential_evolution step 68: f(x)= 1.1398997246132436
# differential_evolution step 69: f(x)= 1.1398997246132436
# differential_evolution step 70: f(x)= 1.1398997246132436
# differential_evolution step 71: f(x)= 1.1398997246132436
# differential_evolution step 72: f(x)= 1.1365780060265813
# differential_evolution step 73: f(x)= 1.1365780060265813
# differential_evolution step 74: f(x)= 1.1365780060265813
# differential_evolution step 75: f(x)= 1.1365780060265813
# differential_evolution step 76: f(x)= 1.1365780060265813
# differential_evolution step 77: f(x)= 1.130037189744973
# differential_evolution step 78: f(x)= 1.130037189744973
# differential_evolution step 79: f(x)= 1.130037189744973
# differential_evolution step 80: f(x)= 1.130037189744973
# differential_evolution step 81: f(x)= 1.130037189744973
# differential_evolution step 82: f(x)= 1.130037189744973
# differential_evolution step 83: f(x)= 1.1293908945917808
# differential_evolution step 84: f(x)= 1.1293908945917808
# differential_evolution step 85: f(x)= 1.1293908945917808
# differential_evolution step 86: f(x)= 1.1293908945917808
# differential_evolution step 87: f(x)= 1.1293908945917808
# differential_evolution step 88: f(x)= 1.1293908945917808
# differential_evolution step 89: f(x)= 1.128514698462231
# differential_evolution step 90: f(x)= 1.128514698462231
# differential_evolution step 91: f(x)= 1.128514698462231
# differential_evolution step 92: f(x)= 1.128514698462231
# differential_evolution step 93: f(x)= 1.128514698462231
# differential_evolution step 94: f(x)= 1.128514698462231
# differential_evolution step 95: f(x)= 1.128514698462231
# differential_evolution step 96: f(x)= 1.128514698462231
# differential_evolution step 97: f(x)= 1.128514698462231
# differential_evolution step 98: f(x)= 1.128514698462231
# differential_evolution step 99: f(x)= 1.1284230452198354
# differential_evolution step 100: f(x)= 1.1284230452198354
# differential_evolution step 101: f(x)= 1.127288476412033
# differential_evolution step 102: f(x)= 1.127288476412033
# differential_evolution step 103: f(x)= 1.127288476412033
# differential_evolution step 104: f(x)= 1.127288476412033
# differential_evolution step 105: f(x)= 1.127288476412033
# differential_evolution step 106: f(x)= 1.127288476412033
# differential_evolution step 107: f(x)= 1.1271528116697203
# differential_evolution step 108: f(x)= 1.1271528116697203
# differential_evolution step 109: f(x)= 1.1271528116697203
# differential_evolution step 110: f(x)= 1.1271528116697203
# differential_evolution step 111: f(x)= 1.1271528116697203
# differential_evolution step 112: f(x)= 1.1269276549233982
# differential_evolution step 113: f(x)= 1.1268915407776905
# differential_evolution step 114: f(x)= 1.1268915407776905
# differential_evolution step 115: f(x)= 1.1268915407776905
# differential_evolution step 116: f(x)= 1.1268915407776905
# differential_evolution step 117: f(x)= 1.1268915407776905
# differential_evolution step 118: f(x)= 1.1268563644810936
# differential_evolution step 119: f(x)= 1.126785090660732
# differential_evolution step 120: f(x)= 1.126785090660732
# differential_evolution step 121: f(x)= 1.126695061510355
# differential_evolution step 122: f(x)= 1.126695061510355
# differential_evolution step 123: f(x)= 1.126695061510355
# differential_evolution step 124: f(x)= 1.126656691071704
# differential_evolution step 125: f(x)= 1.126656691071704
# differential_evolution step 126: f(x)= 1.126656691071704
# differential_evolution step 127: f(x)= 1.126656691071704
# differential_evolution step 128: f(x)= 1.126656691071704
# differential_evolution step 129: f(x)= 1.126656691071704
# differential_evolution step 130: f(x)= 1.126622838019323
# differential_evolution step 131: f(x)= 1.126622838019323
# differential_evolution step 132: f(x)= 1.126622838019323
# differential_evolution step 133: f(x)= 1.126622838019323
# differential_evolution step 134: f(x)= 1.126611599683307
# differential_evolution step 135: f(x)= 1.126611599683307
# differential_evolution step 136: f(x)= 1.1265429880788362
# differential_evolution step 137: f(x)= 1.1265429880788362
# differential_evolution step 138: f(x)= 1.1265429880788362
# differential_evolution step 139: f(x)= 1.1265429880788362
# differential_evolution step 140: f(x)= 1.1265429880788362
# differential_evolution step 141: f(x)= 1.1265429880788362
# differential_evolution step 142: f(x)= 1.1265362246155488
# differential_evolution step 143: f(x)= 1.126536169045026
# differential_evolution step 144: f(x)= 1.1265267030734856
# differential_evolution step 145: f(x)= 1.1265267030734856
# differential_evolution step 146: f(x)= 1.1265173778865112
# differential_evolution step 147: f(x)= 1.1265173778865112
# differential_evolution step 148: f(x)= 1.126502878549711
# differential_evolution step 149: f(x)= 1.126502878549711
# differential_evolution step 150: f(x)= 1.126502878549711
# differential_evolution step 151: f(x)= 1.1265001950555598
# differential_evolution step 152: f(x)= 1.1265001950555598
# differential_evolution step 153: f(x)= 1.126493603137241
# differential_evolution step 154: f(x)= 1.126493603137241
# differential_evolution step 155: f(x)= 1.126493603137241
# differential_evolution step 156: f(x)= 1.126493603137241
# differential_evolution step 157: f(x)= 1.1264884298435922
# differential_evolution step 158: f(x)= 1.1264884298435922
# differential_evolution step 159: f(x)= 1.1264884298435922
# differential_evolution step 160: f(x)= 1.126488423023383
# differential_evolution step 161: f(x)= 1.126488423023383
# differential_evolution step 162: f(x)= 1.126488423023383
# differential_evolution step 163: f(x)= 1.126488423023383
# differential_evolution step 164: f(x)= 1.126488423023383
# differential_evolution step 165: f(x)= 1.126488423023383
# differential_evolution step 166: f(x)= 1.126488423023383
# differential_evolution step 167: f(x)= 1.1264879297066948
# differential_evolution step 168: f(x)= 1.1264879297066948
# differential_evolution step 169: f(x)= 1.1264874847162814
# differential_evolution step 170: f(x)= 1.1264874847162814
# differential_evolution step 171: f(x)= 1.1264874847162814
# differential_evolution step 172: f(x)= 1.1264831853185264
# differential_evolution step 173: f(x)= 1.1264821875977546
# differential_evolution step 174: f(x)= 1.1264821875977546
# differential_evolution step 175: f(x)= 1.1264821875977546
# differential_evolution step 176: f(x)= 1.1264821660946187
# differential_evolution step 177: f(x)= 1.1264817952425807
# differential_evolution step 178: f(x)= 1.1264817952425807
# differential_evolution step 179: f(x)= 1.1264817952425807
# differential_evolution step 180: f(x)= 1.1264812652513976
# differential_evolution step 181: f(x)= 1.126479999714449
# differential_evolution step 182: f(x)= 1.126478401217707
# differential_evolution step 183: f(x)= 1.126478401217707
# differential_evolution step 184: f(x)= 1.126478401217707
# differential_evolution step 185: f(x)= 1.126478401217707
# differential_evolution step 186: f(x)= 1.126478401217707
# differential_evolution step 187: f(x)= 1.126478029238534
# differential_evolution step 188: f(x)= 1.126478029238534
# differential_evolution step 189: f(x)= 1.1264770843528624
# differential_evolution step 190: f(x)= 1.1264770843528624
# differential_evolution step 191: f(x)= 1.1264770843528624
# differential_evolution step 192: f(x)= 1.1264770843528624
# differential_evolution step 193: f(x)= 1.1264770843528624
# differential_evolution step 194: f(x)= 1.1264770843528624
# differential_evolution step 195: f(x)= 1.1264769000793957
# differential_evolution step 196: f(x)= 1.1264769000793957
# differential_evolution step 197: f(x)= 1.1264769000793957
# differential_evolution step 198: f(x)= 1.1264769000793957
# differential_evolution step 199: f(x)= 1.1264769000793957
# differential_evolution step 200: f(x)= 1.1264769000793957
# differential_evolution step 201: f(x)= 1.1264769000793957
# differential_evolution step 202: f(x)= 1.1264769000793957
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.11032493 49.99998404  1.57579747 56.12228057  0.43246152  2.77381859
#   0.59568806 86.43874265]
# Chi quadro minimo: 1.1264767518760994

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0220, r_e=195.6359, n=2.6093, x_0=56.1139
# Sérsic 2: I_e=0.4884, r_e=2.4772, n=0.4929, x_0=86.4424
# [1.34579114e-02 1.03449949e+02 4.04545912e-01 2.66347181e-01
#  2.34444727e-01 4.73225145e-01 3.77060828e-01 2.37926057e-01]
# 37.08095792389502
# 54.663375506312605 37.08095792389502 73.92231941179975 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 7215.50823352786
# differential_evolution step 2: f(x)= 702.636709444088
# differential_evolution step 3: f(x)= 702.636709444088
# differential_evolution step 4: f(x)= 702.636709444088
# differential_evolution step 5: f(x)= 224.09147715858322
# differential_evolution step 6: f(x)= 197.6890964246751
# differential_evolution step 7: f(x)= 52.37154820696317
# differential_evolution step 8: f(x)= 52.37154820696317
# differential_evolution step 9: f(x)= 52.37154820696317
# differential_evolution step 10: f(x)= 52.37154820696317
# differential_evolution step 11: f(x)= 52.37154820696317
# differential_evolution step 12: f(x)= 15.070224803269682
# differential_evolution step 13: f(x)= 15.070224803269682
# differential_evolution step 14: f(x)= 4.281114635977031
# differential_evolution step 15: f(x)= 4.281114635977031
# differential_evolution step 16: f(x)= 4.281114635977031
# differential_evolution step 17: f(x)= 4.281114635977031
# differential_evolution step 18: f(x)= 4.281114635977031
# differential_evolution step 19: f(x)= 4.281114635977031
# differential_evolution step 20: f(x)= 4.281114635977031
# differential_evolution step 21: f(x)= 4.281114635977031
# differential_evolution step 22: f(x)= 4.281114635977031
# differential_evolution step 23: f(x)= 4.281114635977031
# differential_evolution step 24: f(x)= 4.281114635977031
# differential_evolution step 25: f(x)= 4.281114635977031
# differential_evolution step 26: f(x)= 4.281114635977031
# differential_evolution step 27: f(x)= 4.281114635977031
# differential_evolution step 28: f(x)= 3.7046953885338794
# differential_evolution step 29: f(x)= 3.7046953885338794
# differential_evolution step 30: f(x)= 3.7046953885338794
# differential_evolution step 31: f(x)= 3.7046953885338794
# differential_evolution step 32: f(x)= 3.7046953885338794
# differential_evolution step 33: f(x)= 3.7046953885338794
# differential_evolution step 34: f(x)= 3.7046953885338794
# differential_evolution step 35: f(x)= 3.7046953885338794
# differential_evolution step 36: f(x)= 3.7046953885338794
# differential_evolution step 37: f(x)= 3.7046953885338794
# differential_evolution step 38: f(x)= 3.7046953885338794
# differential_evolution step 39: f(x)= 3.7046953885338794
# differential_evolution step 40: f(x)= 3.6263693339309926
# differential_evolution step 41: f(x)= 3.6263693339309926
# differential_evolution step 42: f(x)= 3.6263693339309926
# differential_evolution step 43: f(x)= 2.878723257209059
# differential_evolution step 44: f(x)= 2.878723257209059
# differential_evolution step 45: f(x)= 2.878723257209059
# differential_evolution step 46: f(x)= 2.878723257209059
# differential_evolution step 47: f(x)= 2.878723257209059
# differential_evolution step 48: f(x)= 2.878723257209059
# differential_evolution step 49: f(x)= 2.878723257209059
# differential_evolution step 50: f(x)= 2.878723257209059
# differential_evolution step 51: f(x)= 2.878723257209059
# differential_evolution step 52: f(x)= 2.6947161065547345
# differential_evolution step 53: f(x)= 2.6947161065547345
# differential_evolution step 54: f(x)= 2.5571788040981933
# differential_evolution step 55: f(x)= 2.5571788040981933
# differential_evolution step 56: f(x)= 2.5571788040981933
# differential_evolution step 57: f(x)= 2.5571788040981933
# differential_evolution step 58: f(x)= 2.5571788040981933
# differential_evolution step 59: f(x)= 2.5571788040981933
# differential_evolution step 60: f(x)= 2.5571788040981933
# differential_evolution step 61: f(x)= 2.3404320411642963
# differential_evolution step 62: f(x)= 1.8662767070870665
# differential_evolution step 63: f(x)= 1.8662767070870665
# differential_evolution step 64: f(x)= 1.8662767070870665
# differential_evolution step 65: f(x)= 1.8662767070870665
# differential_evolution step 66: f(x)= 1.8635367546581278
# differential_evolution step 67: f(x)= 1.7606826451728719
# differential_evolution step 68: f(x)= 1.7606826451728719
# differential_evolution step 69: f(x)= 1.7606826451728719
# differential_evolution step 70: f(x)= 1.7606826451728719
# differential_evolution step 71: f(x)= 1.7606826451728719
# differential_evolution step 72: f(x)= 1.7606826451728719
# differential_evolution step 73: f(x)= 1.7606826451728719
# differential_evolution step 74: f(x)= 1.7606826451728719
# differential_evolution step 75: f(x)= 1.7606826451728719
# differential_evolution step 76: f(x)= 1.7606826451728719
# differential_evolution step 77: f(x)= 1.7585030728514477
# differential_evolution step 78: f(x)= 1.6171614648239658
# differential_evolution step 79: f(x)= 1.5624475818488224
# differential_evolution step 80: f(x)= 1.4824916791451477
# differential_evolution step 81: f(x)= 1.3076826327213915
# differential_evolution step 82: f(x)= 1.3076826327213915
# differential_evolution step 83: f(x)= 1.3076826327213915
# differential_evolution step 84: f(x)= 1.150814770935803
# differential_evolution step 85: f(x)= 1.150814770935803
# differential_evolution step 86: f(x)= 1.150814770935803
# differential_evolution step 87: f(x)= 1.1344545733097335
# differential_evolution step 88: f(x)= 1.1344545733097335
# differential_evolution step 89: f(x)= 1.1344545733097335
# differential_evolution step 90: f(x)= 1.1344545733097335
# differential_evolution step 91: f(x)= 1.1344545733097335
# differential_evolution step 92: f(x)= 1.1344545733097335
# differential_evolution step 93: f(x)= 1.1344545733097335
# differential_evolution step 94: f(x)= 1.1344545733097335
# differential_evolution step 95: f(x)= 1.1344545733097335
# differential_evolution step 96: f(x)= 1.1344545733097335
# differential_evolution step 97: f(x)= 1.1239272835307157
# differential_evolution step 98: f(x)= 1.1239272835307157
# differential_evolution step 99: f(x)= 1.1239272835307157
# differential_evolution step 100: f(x)= 1.1239272835307157
# differential_evolution step 101: f(x)= 1.1239272835307157
# differential_evolution step 102: f(x)= 1.1239272835307157
# differential_evolution step 103: f(x)= 1.1239272835307157
# differential_evolution step 104: f(x)= 1.1239272835307157
# differential_evolution step 105: f(x)= 1.1239272835307157
# differential_evolution step 106: f(x)= 1.0753937398864402
# differential_evolution step 107: f(x)= 1.0566530964590672
# differential_evolution step 108: f(x)= 1.0566530964590672
# differential_evolution step 109: f(x)= 1.0566530964590672
# differential_evolution step 110: f(x)= 1.0377086533806812
# differential_evolution step 111: f(x)= 1.0377086533806812
# differential_evolution step 112: f(x)= 0.9868348805014471
# differential_evolution step 113: f(x)= 0.9868348805014471
# differential_evolution step 114: f(x)= 0.9868348805014471
# differential_evolution step 115: f(x)= 0.9868348805014471
# differential_evolution step 116: f(x)= 0.9868348805014471
# differential_evolution step 117: f(x)= 0.9868348805014471
# differential_evolution step 118: f(x)= 0.9868348805014471
# differential_evolution step 119: f(x)= 0.9868348805014471
# differential_evolution step 120: f(x)= 0.9868348805014471
# differential_evolution step 121: f(x)= 0.9868348805014471
# differential_evolution step 122: f(x)= 0.9482278378389887
# differential_evolution step 123: f(x)= 0.9482278378389887
# differential_evolution step 124: f(x)= 0.9482278378389887
# differential_evolution step 125: f(x)= 0.9482278378389887
# differential_evolution step 126: f(x)= 0.9482278378389887
# differential_evolution step 127: f(x)= 0.9375596840683984
# differential_evolution step 128: f(x)= 0.9375596840683984
# differential_evolution step 129: f(x)= 0.9375596840683984
# differential_evolution step 130: f(x)= 0.9375596840683984
# differential_evolution step 131: f(x)= 0.9375596840683984
# differential_evolution step 132: f(x)= 0.9375596840683984
# differential_evolution step 133: f(x)= 0.9375596840683984
# differential_evolution step 134: f(x)= 0.9375596840683984
# differential_evolution step 135: f(x)= 0.9340320066732077
# differential_evolution step 136: f(x)= 0.9340320066732077
# differential_evolution step 137: f(x)= 0.9340320066732077
# differential_evolution step 138: f(x)= 0.9072218604304475
# differential_evolution step 139: f(x)= 0.9072218604304475
# differential_evolution step 140: f(x)= 0.9072218604304475
# differential_evolution step 141: f(x)= 0.9072218604304475
# differential_evolution step 142: f(x)= 0.8922516108822328
# differential_evolution step 143: f(x)= 0.8922516108822328
# differential_evolution step 144: f(x)= 0.8922516108822328
# differential_evolution step 145: f(x)= 0.8922516108822328
# differential_evolution step 146: f(x)= 0.8922516108822328
# differential_evolution step 147: f(x)= 0.8922516108822328
# differential_evolution step 148: f(x)= 0.8894147638913931
# differential_evolution step 149: f(x)= 0.8749929657073192
# differential_evolution step 150: f(x)= 0.8749929657073192
# differential_evolution step 151: f(x)= 0.8749929657073192
# differential_evolution step 152: f(x)= 0.8749929657073192
# differential_evolution step 153: f(x)= 0.8749929657073192
# differential_evolution step 154: f(x)= 0.8732950813775175
# differential_evolution step 155: f(x)= 0.8732950813775175
# differential_evolution step 156: f(x)= 0.8732950813775175
# differential_evolution step 157: f(x)= 0.8732950813775175
# differential_evolution step 158: f(x)= 0.8732950813775175
# differential_evolution step 159: f(x)= 0.8509277790875326
# differential_evolution step 160: f(x)= 0.8509277790875326
# differential_evolution step 161: f(x)= 0.8509277790875326
# differential_evolution step 162: f(x)= 0.8509277790875326
# differential_evolution step 163: f(x)= 0.8509277790875326
# differential_evolution step 164: f(x)= 0.8509277790875326
# differential_evolution step 165: f(x)= 0.8509277790875326
# differential_evolution step 166: f(x)= 0.8345219766926669
# differential_evolution step 167: f(x)= 0.8345219766926669
# differential_evolution step 168: f(x)= 0.8345219766926669
# differential_evolution step 169: f(x)= 0.8345219766926669
# differential_evolution step 170: f(x)= 0.8345219766926669
# differential_evolution step 171: f(x)= 0.8344022443599265
# differential_evolution step 172: f(x)= 0.8337557145727948
# differential_evolution step 173: f(x)= 0.8337557145727948
# differential_evolution step 174: f(x)= 0.8337557145727948
# differential_evolution step 175: f(x)= 0.8334329761364925
# differential_evolution step 176: f(x)= 0.8327179307822784
# differential_evolution step 177: f(x)= 0.8279278317497974
# differential_evolution step 178: f(x)= 0.8171040561117321
# differential_evolution step 179: f(x)= 0.8136659376464827
# differential_evolution step 180: f(x)= 0.8136659376464827
# differential_evolution step 181: f(x)= 0.8136659376464827
# differential_evolution step 182: f(x)= 0.8136659376464827
# differential_evolution step 183: f(x)= 0.8136659376464827
# differential_evolution step 184: f(x)= 0.8136659376464827
# differential_evolution step 185: f(x)= 0.8136659376464827
# differential_evolution step 186: f(x)= 0.8136659376464827
# differential_evolution step 187: f(x)= 0.8136659376464827
# differential_evolution step 188: f(x)= 0.8136659376464827
# differential_evolution step 189: f(x)= 0.8136659376464827
# differential_evolution step 190: f(x)= 0.8106215173591687
# differential_evolution step 191: f(x)= 0.8100677574171453
# differential_evolution step 192: f(x)= 0.8100677574171453
# differential_evolution step 193: f(x)= 0.8091292555376293
# differential_evolution step 194: f(x)= 0.8091292555376293
# differential_evolution step 195: f(x)= 0.8091292555376293
# differential_evolution step 196: f(x)= 0.8091292555376293
# differential_evolution step 197: f(x)= 0.8029844504960417
# differential_evolution step 198: f(x)= 0.8029844504960417
# differential_evolution step 199: f(x)= 0.8029844504960417
# differential_evolution step 200: f(x)= 0.801615467863173
# differential_evolution step 201: f(x)= 0.801615467863173
# differential_evolution step 202: f(x)= 0.801615467863173
# differential_evolution step 203: f(x)= 0.801615467863173
# differential_evolution step 204: f(x)= 0.801615467863173
# differential_evolution step 205: f(x)= 0.8003360527506711
# differential_evolution step 206: f(x)= 0.8003360527506711
# differential_evolution step 207: f(x)= 0.7969747551038512
# differential_evolution step 208: f(x)= 0.7907107892176831
# differential_evolution step 209: f(x)= 0.7907107892176831
# differential_evolution step 210: f(x)= 0.7907107892176831
# differential_evolution step 211: f(x)= 0.7907107892176831
# differential_evolution step 212: f(x)= 0.7907107892176831
# differential_evolution step 213: f(x)= 0.7907107892176831
# differential_evolution step 214: f(x)= 0.7907107892176831
# differential_evolution step 215: f(x)= 0.7907107892176831
# differential_evolution step 216: f(x)= 0.7895333473510042
# differential_evolution step 217: f(x)= 0.7895333473510042
# differential_evolution step 218: f(x)= 0.7895333473510042
# differential_evolution step 219: f(x)= 0.7895333473510042
# differential_evolution step 220: f(x)= 0.7895333473510042
# differential_evolution step 221: f(x)= 0.7895333473510042
# differential_evolution step 222: f(x)= 0.7895333473510042
# differential_evolution step 223: f(x)= 0.7895333473510042
# differential_evolution step 224: f(x)= 0.7895333473510042
# differential_evolution step 225: f(x)= 0.7895333473510042
# differential_evolution step 226: f(x)= 0.7895333473510042
# differential_evolution step 227: f(x)= 0.7832624359686172
# differential_evolution step 228: f(x)= 0.7832624359686172
# differential_evolution step 229: f(x)= 0.7832624359686172
# differential_evolution step 230: f(x)= 0.7832624359686172
# differential_evolution step 231: f(x)= 0.7832624359686172
# differential_evolution step 232: f(x)= 0.7796764904566638
# differential_evolution step 233: f(x)= 0.7796764904566638
# differential_evolution step 234: f(x)= 0.7749286959740509
# differential_evolution step 235: f(x)= 0.7718890811564801
# differential_evolution step 236: f(x)= 0.7718890811564801
# differential_evolution step 237: f(x)= 0.7718890811564801
# differential_evolution step 238: f(x)= 0.7718890811564801
# differential_evolution step 239: f(x)= 0.7718890811564801
# differential_evolution step 240: f(x)= 0.7718890811564801
# differential_evolution step 241: f(x)= 0.7718890811564801
# differential_evolution step 242: f(x)= 0.7718890811564801
# differential_evolution step 243: f(x)= 0.7715140154888643
# differential_evolution step 244: f(x)= 0.7715140154888643
# differential_evolution step 245: f(x)= 0.7689540197899313
# differential_evolution step 246: f(x)= 0.7689540197899313
# differential_evolution step 247: f(x)= 0.7689540197899313
# differential_evolution step 248: f(x)= 0.7689540197899313
# differential_evolution step 249: f(x)= 0.7689540197899313
# differential_evolution step 250: f(x)= 0.7689540197899313
# differential_evolution step 251: f(x)= 0.7689540197899313
# differential_evolution step 252: f(x)= 0.7667481757111342
# differential_evolution step 253: f(x)= 0.766383415327482
# differential_evolution step 254: f(x)= 0.766383415327482
# differential_evolution step 255: f(x)= 0.7641953980950913
# differential_evolution step 256: f(x)= 0.7641953980950913
# differential_evolution step 257: f(x)= 0.7641953980950913
# differential_evolution step 258: f(x)= 0.7641953980950913
# differential_evolution step 259: f(x)= 0.7641953980950913
# differential_evolution step 260: f(x)= 0.7635837748113516
# differential_evolution step 261: f(x)= 0.7635837748113516
# differential_evolution step 262: f(x)= 0.7635837748113516
# differential_evolution step 263: f(x)= 0.7635837748113516
# differential_evolution step 264: f(x)= 0.7635837748113516
# differential_evolution step 265: f(x)= 0.7635837748113516
# differential_evolution step 266: f(x)= 0.7635837748113516
# differential_evolution step 267: f(x)= 0.7635837748113516
# differential_evolution step 268: f(x)= 0.7635837748113516
# differential_evolution step 269: f(x)= 0.7635837748113516
# differential_evolution step 270: f(x)= 0.7635837748113516
# differential_evolution step 271: f(x)= 0.7635837748113516
# differential_evolution step 272: f(x)= 0.7635837748113516
# differential_evolution step 273: f(x)= 0.7635837748113516
# differential_evolution step 274: f(x)= 0.7635837748113516
# differential_evolution step 275: f(x)= 0.7635837748113516
# differential_evolution step 276: f(x)= 0.7635837748113516
# differential_evolution step 277: f(x)= 0.762155163654111
# differential_evolution step 278: f(x)= 0.762155163654111
# differential_evolution step 279: f(x)= 0.762155163654111
# differential_evolution step 280: f(x)= 0.762155163654111
# differential_evolution step 281: f(x)= 0.762155163654111
# differential_evolution step 282: f(x)= 0.762155163654111
# differential_evolution step 283: f(x)= 0.762155163654111
# differential_evolution step 284: f(x)= 0.7604937605298177
# differential_evolution step 285: f(x)= 0.7604937605298177
# differential_evolution step 286: f(x)= 0.7604937605298177
# differential_evolution step 287: f(x)= 0.7604937605298177
# differential_evolution step 288: f(x)= 0.7604937605298177
# differential_evolution step 289: f(x)= 0.7604937605298177
# differential_evolution step 290: f(x)= 0.7597936958981597
# differential_evolution step 291: f(x)= 0.7597936958981597
# differential_evolution step 292: f(x)= 0.7591420368179365
# differential_evolution step 293: f(x)= 0.7591420368179365
# differential_evolution step 294: f(x)= 0.7591420368179365
# differential_evolution step 295: f(x)= 0.7591420368179365
# differential_evolution step 296: f(x)= 0.7591420368179365
# differential_evolution step 297: f(x)= 0.7591420368179365
# differential_evolution step 298: f(x)= 0.7584950699001359
# differential_evolution step 299: f(x)= 0.7584950699001359
# differential_evolution step 300: f(x)= 0.7584950699001359
# differential_evolution step 301: f(x)= 0.7584950699001359
# differential_evolution step 302: f(x)= 0.7584950699001359
# differential_evolution step 303: f(x)= 0.7584950699001359
# differential_evolution step 304: f(x)= 0.7584950699001359
# differential_evolution step 305: f(x)= 0.7584950699001359
# differential_evolution step 306: f(x)= 0.7584950699001359
# differential_evolution step 307: f(x)= 0.7584950699001359
# differential_evolution step 308: f(x)= 0.7584950699001359
# differential_evolution step 309: f(x)= 0.7582010967164408
# differential_evolution step 310: f(x)= 0.7582010967164408
# differential_evolution step 311: f(x)= 0.7574457954710914
# differential_evolution step 312: f(x)= 0.7574457954710914
# differential_evolution step 313: f(x)= 0.7574457954710914
# differential_evolution step 314: f(x)= 0.7574457954710914
# differential_evolution step 315: f(x)= 0.7574457954710914
# differential_evolution step 316: f(x)= 0.7574457954710914
# differential_evolution step 317: f(x)= 0.7574457954710914
# differential_evolution step 318: f(x)= 0.7574457954710914
# differential_evolution step 319: f(x)= 0.7574457954710914
# differential_evolution step 320: f(x)= 0.7574457954710914
# differential_evolution step 321: f(x)= 0.7574457954710914
# differential_evolution step 322: f(x)= 0.7574457954710914
# differential_evolution step 323: f(x)= 0.7574457954710914
# differential_evolution step 324: f(x)= 0.7574457954710914
# differential_evolution step 325: f(x)= 0.7572886773276007
# differential_evolution step 326: f(x)= 0.7572886773276007
# differential_evolution step 327: f(x)= 0.7572886773276007
# differential_evolution step 328: f(x)= 0.7572886773276007
# differential_evolution step 329: f(x)= 0.7572886773276007
# differential_evolution step 330: f(x)= 0.7572886773276007
# differential_evolution step 331: f(x)= 0.7572886773276007
# differential_evolution step 332: f(x)= 0.7572886773276007
# differential_evolution step 333: f(x)= 0.7572886773276007
# differential_evolution step 334: f(x)= 0.7572886773276007
# differential_evolution step 335: f(x)= 0.7572886773276007
# differential_evolution step 336: f(x)= 0.7572886773276007
# differential_evolution step 337: f(x)= 0.7570453474331025
# differential_evolution step 338: f(x)= 0.7570453474331025
# differential_evolution step 339: f(x)= 0.7570453474331025
# differential_evolution step 340: f(x)= 0.7570453474331025
# differential_evolution step 341: f(x)= 0.7570397015506102
# differential_evolution step 342: f(x)= 0.7570397015506102
# differential_evolution step 343: f(x)= 0.7570397015506102
# differential_evolution step 344: f(x)= 0.7570397015506102
# differential_evolution step 345: f(x)= 0.7570397015506102
# differential_evolution step 346: f(x)= 0.7570397015506102
# differential_evolution step 347: f(x)= 0.7570397015506102
# differential_evolution step 348: f(x)= 0.7570397015506102
# differential_evolution step 349: f(x)= 0.7570397015506102
# differential_evolution step 350: f(x)= 0.7570397015506102
# differential_evolution step 351: f(x)= 0.7568941944907426
# differential_evolution step 352: f(x)= 0.7568941944907426
# differential_evolution step 353: f(x)= 0.7568941944907426
# differential_evolution step 354: f(x)= 0.7568447859751142
# differential_evolution step 355: f(x)= 0.7568447859751142
# differential_evolution step 356: f(x)= 0.756821721711199
# differential_evolution step 357: f(x)= 0.756821721711199
# differential_evolution step 358: f(x)= 0.756821721711199
# differential_evolution step 359: f(x)= 0.756821721711199
# differential_evolution step 360: f(x)= 0.756821721711199
# differential_evolution step 361: f(x)= 0.756821721711199
# differential_evolution step 362: f(x)= 0.7567857397747005
# differential_evolution step 363: f(x)= 0.7567857397747005
# differential_evolution step 364: f(x)= 0.7567857397747005
# differential_evolution step 365: f(x)= 0.7567857397747005
# differential_evolution step 366: f(x)= 0.7567857397747005
# differential_evolution step 367: f(x)= 0.7567857397747005
# differential_evolution step 368: f(x)= 0.7567857397747005
# differential_evolution step 369: f(x)= 0.7567857397747005
# differential_evolution step 370: f(x)= 0.7567857397747005
# differential_evolution step 371: f(x)= 0.7567857397747005
# differential_evolution step 372: f(x)= 0.7567857397747005
# differential_evolution step 373: f(x)= 0.7567857397747005
# differential_evolution step 374: f(x)= 0.7567857397747005
# differential_evolution step 375: f(x)= 0.7567857397747005
# differential_evolution step 376: f(x)= 0.7567857397747005
# differential_evolution step 377: f(x)= 0.7567857397747005
# differential_evolution step 378: f(x)= 0.7567857397747005
# differential_evolution step 379: f(x)= 0.7567857397747005
# differential_evolution step 380: f(x)= 0.7567576642494125
# differential_evolution step 381: f(x)= 0.7567576642494125
# differential_evolution step 382: f(x)= 0.7567576642494125
# differential_evolution step 383: f(x)= 0.7567576642494125
# differential_evolution step 384: f(x)= 0.7567576642494125
# differential_evolution step 385: f(x)= 0.7567576642494125
# differential_evolution step 386: f(x)= 0.7567302457275202
# differential_evolution step 387: f(x)= 0.7567302457275202
# differential_evolution step 388: f(x)= 0.7567302457275202
# differential_evolution step 389: f(x)= 0.7567172184188653
# differential_evolution step 390: f(x)= 0.7567172184188653
# differential_evolution step 391: f(x)= 0.756661946422303
# differential_evolution step 392: f(x)= 0.7566245157442242
# differential_evolution step 393: f(x)= 0.7566245157442242
# differential_evolution step 394: f(x)= 0.7566245157442242
# differential_evolution step 395: f(x)= 0.7566245157442242
# differential_evolution step 396: f(x)= 0.7566245157442242
# differential_evolution step 397: f(x)= 0.7566245157442242
# differential_evolution step 398: f(x)= 0.7566245157442242
# differential_evolution step 399: f(x)= 0.7566245157442242
# differential_evolution step 400: f(x)= 0.7566245157442242
# differential_evolution step 401: f(x)= 0.7566245157442242
# differential_evolution step 402: f(x)= 0.7566245157442242
# differential_evolution step 403: f(x)= 0.7566245157442242
# differential_evolution step 404: f(x)= 0.7566180259289944
# differential_evolution step 405: f(x)= 0.7566180259289944
# differential_evolution step 406: f(x)= 0.7566180259289944
# differential_evolution step 407: f(x)= 0.7566180259289944
# differential_evolution step 408: f(x)= 0.7566180259289944
# differential_evolution step 409: f(x)= 0.7566180259289944
# differential_evolution step 410: f(x)= 0.7566180259289944
# differential_evolution step 411: f(x)= 0.7566138628505319
# differential_evolution step 412: f(x)= 0.7566089793211577
# differential_evolution step 413: f(x)= 0.7566089793211577
# differential_evolution step 414: f(x)= 0.7565927093178699
# differential_evolution step 415: f(x)= 0.7565927093178699
# differential_evolution step 416: f(x)= 0.7565927093178699
# differential_evolution step 417: f(x)= 0.7565927093178699
# differential_evolution step 418: f(x)= 0.7565927093178699
# differential_evolution step 419: f(x)= 0.7565927093178699
# differential_evolution step 420: f(x)= 0.7565530750147827
# differential_evolution step 421: f(x)= 0.7565530750147827
# differential_evolution step 422: f(x)= 0.7565530750147827
# differential_evolution step 423: f(x)= 0.7565530750147827
# differential_evolution step 424: f(x)= 0.7565498327693907
# differential_evolution step 425: f(x)= 0.7565382013684789
# differential_evolution step 426: f(x)= 0.7565363984173661
# differential_evolution step 427: f(x)= 0.7565317016744497
# differential_evolution step 428: f(x)= 0.7565317016744497
# differential_evolution step 429: f(x)= 0.7565317016744497
# differential_evolution step 430: f(x)= 0.7565317016744497
# differential_evolution step 431: f(x)= 0.7565317016744497
# differential_evolution step 432: f(x)= 0.7565177457209091
# differential_evolution step 433: f(x)= 0.7565177457209091
# differential_evolution step 434: f(x)= 0.7565177457209091
# differential_evolution step 435: f(x)= 0.7565177457209091
# differential_evolution step 436: f(x)= 0.756514320475212
# differential_evolution step 437: f(x)= 0.756514320475212
# differential_evolution step 438: f(x)= 0.756514320475212
# differential_evolution step 439: f(x)= 0.756514320475212
# differential_evolution step 440: f(x)= 0.756514320475212
# differential_evolution step 441: f(x)= 0.756514320475212
# differential_evolution step 442: f(x)= 0.756514320475212
# differential_evolution step 443: f(x)= 0.7565100468104363
# differential_evolution step 444: f(x)= 0.7565100468104363
# differential_evolution step 445: f(x)= 0.7565100468104363
# differential_evolution step 446: f(x)= 0.7565017683922862
# differential_evolution step 447: f(x)= 0.7565017683922862
# differential_evolution step 448: f(x)= 0.7565017683922862
# differential_evolution step 449: f(x)= 0.7565017683922862
# differential_evolution step 450: f(x)= 0.7565017683922862
# differential_evolution step 451: f(x)= 0.7565017683922862
# differential_evolution step 452: f(x)= 0.7564775656015564
# differential_evolution step 453: f(x)= 0.7564775656015564
# differential_evolution step 454: f(x)= 0.7564775656015564
# differential_evolution step 455: f(x)= 0.7564775656015564
# differential_evolution step 456: f(x)= 0.7564775656015564
# differential_evolution step 457: f(x)= 0.7564610984864478
# differential_evolution step 458: f(x)= 0.7564610984864478
# differential_evolution step 459: f(x)= 0.7564610984864478
# differential_evolution step 460: f(x)= 0.7564513866241641
# differential_evolution step 461: f(x)= 0.7564501614279577
# differential_evolution step 462: f(x)= 0.7564501614279577
# differential_evolution step 463: f(x)= 0.7564501614279577
# differential_evolution step 464: f(x)= 0.7564501614279577
# differential_evolution step 465: f(x)= 0.7564501614279577
# differential_evolution step 466: f(x)= 0.7564501614279577
# differential_evolution step 467: f(x)= 0.7564501614279577
# differential_evolution step 468: f(x)= 0.7564501614279577
# differential_evolution step 469: f(x)= 0.7564501614279577
# differential_evolution step 470: f(x)= 0.7564374691838117
# differential_evolution step 471: f(x)= 0.7564374691838117
# differential_evolution step 472: f(x)= 0.756429820448341
# differential_evolution step 473: f(x)= 0.7564292129819424
# differential_evolution step 474: f(x)= 0.7564292129819424
# differential_evolution step 475: f(x)= 0.7564292129819424
# differential_evolution step 476: f(x)= 0.7564292129819424
# differential_evolution step 477: f(x)= 0.756423842195945
# differential_evolution step 478: f(x)= 0.756423842195945
# differential_evolution step 479: f(x)= 0.756423842195945
# differential_evolution step 480: f(x)= 0.756423842195945
# differential_evolution step 481: f(x)= 0.7564229755001041
# differential_evolution step 482: f(x)= 0.7564164955853478
# differential_evolution step 483: f(x)= 0.7564164955853478
# differential_evolution step 484: f(x)= 0.7564002911892584
# differential_evolution step 485: f(x)= 0.7564002911892584
# differential_evolution step 486: f(x)= 0.7564002911892584
# differential_evolution step 487: f(x)= 0.7563855713227257
# differential_evolution step 488: f(x)= 0.756384717288076
# differential_evolution step 489: f(x)= 0.7563764593296651
# differential_evolution step 490: f(x)= 0.7563764593296651
# differential_evolution step 491: f(x)= 0.7563764593296651
# differential_evolution step 492: f(x)= 0.7563532199274292
# differential_evolution step 493: f(x)= 0.7563532199274292
# differential_evolution step 494: f(x)= 0.7563532199274292
# differential_evolution step 495: f(x)= 0.7563374616585149
# differential_evolution step 496: f(x)= 0.7563374616585149
# differential_evolution step 497: f(x)= 0.7563374616585149
# differential_evolution step 498: f(x)= 0.7563374616585149
# differential_evolution step 499: f(x)= 0.7563374616585149
# differential_evolution step 500: f(x)= 0.7563201620647267
# differential_evolution step 501: f(x)= 0.7563201620647267
# differential_evolution step 502: f(x)= 0.7563201620647267
# differential_evolution step 503: f(x)= 0.7563201620647267
# differential_evolution step 504: f(x)= 0.7563201620647267
# differential_evolution step 505: f(x)= 0.7563201620647267
# differential_evolution step 506: f(x)= 0.7563201620647267
# differential_evolution step 507: f(x)= 0.7563201620647267
# differential_evolution step 508: f(x)= 0.7563161211828112
# differential_evolution step 509: f(x)= 0.7563161211828112
# differential_evolution step 510: f(x)= 0.7563129305640388
# differential_evolution step 511: f(x)= 0.756309013758643
# differential_evolution step 512: f(x)= 0.756309013758643
# differential_evolution step 513: f(x)= 0.756309013758643
# differential_evolution step 514: f(x)= 0.756309013758643
# differential_evolution step 515: f(x)= 0.756309013758643
# differential_evolution step 516: f(x)= 0.756309013758643
# differential_evolution step 517: f(x)= 0.7563059199152227
# differential_evolution step 518: f(x)= 0.7563059199152227
# differential_evolution step 519: f(x)= 0.7563059199152227
# differential_evolution step 520: f(x)= 0.7563052310081645
# differential_evolution step 521: f(x)= 0.7563052310081645
# differential_evolution step 522: f(x)= 0.7563052310081645
# differential_evolution step 523: f(x)= 0.7563052310081645
# differential_evolution step 524: f(x)= 0.7563052310081645
# differential_evolution step 525: f(x)= 0.7563052310081645
# differential_evolution step 526: f(x)= 0.7563052310081645
# differential_evolution step 527: f(x)= 0.7563052310081645
# differential_evolution step 528: f(x)= 0.7563052310081645
# differential_evolution step 529: f(x)= 0.7562878820760427
# differential_evolution step 530: f(x)= 0.7562878820760427
# differential_evolution step 531: f(x)= 0.7562878820760427
# differential_evolution step 532: f(x)= 0.7562878820760427
# differential_evolution step 533: f(x)= 0.7562878820760427
# differential_evolution step 534: f(x)= 0.7562878820760427
# differential_evolution step 535: f(x)= 0.7562878820760427
# differential_evolution step 536: f(x)= 0.7562876974664166
# differential_evolution step 537: f(x)= 0.7562876974664166
# differential_evolution step 538: f(x)= 0.7562876974664166
# differential_evolution step 539: f(x)= 0.7562875064830799
# differential_evolution step 540: f(x)= 0.7562875064830799
# differential_evolution step 541: f(x)= 0.7562875064830799
# differential_evolution step 542: f(x)= 0.7562875064830799
# differential_evolution step 543: f(x)= 0.7562875064830799
# differential_evolution step 544: f(x)= 0.7562875064830799
# differential_evolution step 545: f(x)= 0.7562875064830799
# differential_evolution step 546: f(x)= 0.7562875064830799
# differential_evolution step 547: f(x)= 0.7562849011094848
# differential_evolution step 548: f(x)= 0.7562849011094848
# differential_evolution step 549: f(x)= 0.7562849011094848
# differential_evolution step 550: f(x)= 0.7562849011094848
# differential_evolution step 551: f(x)= 0.7562849011094848
# differential_evolution step 552: f(x)= 0.7562750930175075
# differential_evolution step 553: f(x)= 0.7562750930175075
# differential_evolution step 554: f(x)= 0.7562750930175075
# differential_evolution step 555: f(x)= 0.7562750930175075
# differential_evolution step 556: f(x)= 0.7562750930175075
# differential_evolution step 557: f(x)= 0.7562750930175075
# differential_evolution step 558: f(x)= 0.7562750930175075
# differential_evolution step 559: f(x)= 0.7562750930175075
# differential_evolution step 560: f(x)= 0.7562750930175075
# differential_evolution step 561: f(x)= 0.7562750930175075
# differential_evolution step 562: f(x)= 0.7562705092920721
# differential_evolution step 563: f(x)= 0.7562705092920721
# differential_evolution step 564: f(x)= 0.7562705092920721
# differential_evolution step 565: f(x)= 0.7562705092920721
# differential_evolution step 566: f(x)= 0.7562705092920721
# differential_evolution step 567: f(x)= 0.7562705092920721
# differential_evolution step 568: f(x)= 0.7562705092920721
# differential_evolution step 569: f(x)= 0.7562687187373053
# differential_evolution step 570: f(x)= 0.7562672487149298
# differential_evolution step 571: f(x)= 0.7562672487149298
# differential_evolution step 572: f(x)= 0.7562672487149298
# differential_evolution step 573: f(x)= 0.7562672487149298
# differential_evolution step 574: f(x)= 0.7562672487149298
# differential_evolution step 575: f(x)= 0.7562672487149298
# differential_evolution step 576: f(x)= 0.7562672487149298
# differential_evolution step 577: f(x)= 0.7562672487149298
# differential_evolution step 578: f(x)= 0.7562672487149298
# differential_evolution step 579: f(x)= 0.7562672487149298
# differential_evolution step 580: f(x)= 0.7562672487149298
# differential_evolution step 581: f(x)= 0.7562672487149298
# differential_evolution step 582: f(x)= 0.7562654707240404
# differential_evolution step 583: f(x)= 0.7562654707240404
# differential_evolution step 584: f(x)= 0.7562654707240404
# differential_evolution step 585: f(x)= 0.7562654707240404
# differential_evolution step 586: f(x)= 0.7562654707240404
# differential_evolution step 587: f(x)= 0.7562638017409505
# differential_evolution step 588: f(x)= 0.756262869263853
# differential_evolution step 589: f(x)= 0.756262869263853
# differential_evolution step 590: f(x)= 0.756262869263853
# differential_evolution step 591: f(x)= 0.756262869263853
# differential_evolution step 592: f(x)= 0.756262869263853
# differential_evolution step 593: f(x)= 0.756262869263853
# differential_evolution step 594: f(x)= 0.756262869263853
# differential_evolution step 595: f(x)= 0.756262869263853
# differential_evolution step 596: f(x)= 0.7562605249488598
# differential_evolution step 597: f(x)= 0.7562587649817331
# differential_evolution step 598: f(x)= 0.7562587649817331
# differential_evolution step 599: f(x)= 0.7562587649817331
# differential_evolution step 600: f(x)= 0.7562587649817331
# differential_evolution step 601: f(x)= 0.75625584897328
# differential_evolution step 602: f(x)= 0.75625584897328
# differential_evolution step 603: f(x)= 0.75625584897328
# differential_evolution step 604: f(x)= 0.75625584897328
# differential_evolution step 605: f(x)= 0.75625584897328
# differential_evolution step 606: f(x)= 0.75625584897328
# differential_evolution step 607: f(x)= 0.75625584897328
# differential_evolution step 608: f(x)= 0.75625584897328
# differential_evolution step 609: f(x)= 0.75625584897328
# differential_evolution step 610: f(x)= 0.75625584897328
# differential_evolution step 611: f(x)= 0.75625584897328
# differential_evolution step 612: f(x)= 0.7562540350191623
# differential_evolution step 613: f(x)= 0.7562540350191623
# differential_evolution step 614: f(x)= 0.7562532936623696
# differential_evolution step 615: f(x)= 0.7562532936623696
# differential_evolution step 616: f(x)= 0.7562532936623696
# differential_evolution step 617: f(x)= 0.7562532936623696
# differential_evolution step 618: f(x)= 0.7562532936623696
# differential_evolution step 619: f(x)= 0.7562513988527767
# differential_evolution step 620: f(x)= 0.7562513988527767
# differential_evolution step 621: f(x)= 0.7562513988527767
# differential_evolution step 622: f(x)= 0.7562513988527767
# differential_evolution step 623: f(x)= 0.7562513988527767
# differential_evolution step 624: f(x)= 0.7562513988527767
# differential_evolution step 625: f(x)= 0.7562513988527767
# differential_evolution step 626: f(x)= 0.7562513988527767
# differential_evolution step 627: f(x)= 0.7562513988527767
# differential_evolution step 628: f(x)= 0.7562513988527767
# differential_evolution step 629: f(x)= 0.7562513988527767
# differential_evolution step 630: f(x)= 0.7562513988527767
# differential_evolution step 631: f(x)= 0.7562513988527767
# differential_evolution step 632: f(x)= 0.7562513988527767
# differential_evolution step 633: f(x)= 0.7562513988527767
# differential_evolution step 634: f(x)= 0.7562512245465591
# differential_evolution step 635: f(x)= 0.7562512245465591
# differential_evolution step 636: f(x)= 0.7562512204595072
# differential_evolution step 637: f(x)= 0.7562510710314381
# differential_evolution step 638: f(x)= 0.7562510710314381
# differential_evolution step 639: f(x)= 0.7562506253446123
# differential_evolution step 640: f(x)= 0.7562506253446123
# differential_evolution step 641: f(x)= 0.7562506253446123
# differential_evolution step 642: f(x)= 0.756250435014998
# differential_evolution step 643: f(x)= 0.756250435014998
# differential_evolution step 644: f(x)= 0.756250435014998
# differential_evolution step 645: f(x)= 0.756250435014998
# differential_evolution step 646: f(x)= 0.756250435014998
# differential_evolution step 647: f(x)= 0.7562501854527579
# differential_evolution step 648: f(x)= 0.7562501854527579
# differential_evolution step 649: f(x)= 0.7562501854527579
# differential_evolution step 650: f(x)= 0.7562494355921557
# differential_evolution step 651: f(x)= 0.756249360051519
# differential_evolution step 652: f(x)= 0.756249360051519
# differential_evolution step 653: f(x)= 0.756249360051519
# differential_evolution step 654: f(x)= 0.7562492978817309
# differential_evolution step 655: f(x)= 0.7562492141216501
# differential_evolution step 656: f(x)= 0.7562492141216501
# differential_evolution step 657: f(x)= 0.7562488499959675
# differential_evolution step 658: f(x)= 0.7562488499959675
# differential_evolution step 659: f(x)= 0.7562488499959675
# differential_evolution step 660: f(x)= 0.7562488499959675
# differential_evolution step 661: f(x)= 0.7562488499959675
# differential_evolution step 662: f(x)= 0.7562488499959675
# differential_evolution step 663: f(x)= 0.7562488499959675
# differential_evolution step 664: f(x)= 0.7562488499959675
# differential_evolution step 665: f(x)= 0.7562488499959675
# differential_evolution step 666: f(x)= 0.7562488499959675
# differential_evolution step 667: f(x)= 0.7562488499959675
# differential_evolution step 668: f(x)= 0.7562488499959675
# differential_evolution step 669: f(x)= 0.7562488499959675
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [9.77502170e-02 4.99999617e+01 1.67691323e+00 5.62213055e+01
#  3.96480417e-01 3.03613409e+00 6.64345586e-01 8.64429497e+01
#  4.91801621e-03 4.99863471e+01 2.72063350e+00 1.48167012e+01]
# Chi quadro minimo: 0.7562488499959675

# %%
# Plots:
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\1656088014.py:9: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0605, r_e=75.8611, n=1.9822, x_0=56.1223
# Sérsic 2: I_e=0.4279, r_e=2.8418, n=0.5956, x_0=86.5147
# Sérsic 3: I_e=0.1803, r_e=3.3504, n=0.2250, x_0=14.5001
# [ 0.03359644 33.21484363  0.41422773  0.03985     0.15910577  0.49280253
#   0.29082823  0.20237216  0.08089545  0.59607072  0.41142669  0.59711685]
# 26.661720404837148
# 54.24792730138887 26.661720404837148 81.92376263669425 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (33, 38),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 16238.396713903985
# differential_evolution step 2: f(x)= 12063.081787797026
# differential_evolution step 3: f(x)= 12063.081787797026
# differential_evolution step 4: f(x)= 830.3376244410214
# differential_evolution step 5: f(x)= 830.3376244410214
# differential_evolution step 6: f(x)= 830.3376244410214
# differential_evolution step 7: f(x)= 830.3376244410214
# differential_evolution step 8: f(x)= 830.3376244410214
# differential_evolution step 9: f(x)= 830.3376244410214
# differential_evolution step 10: f(x)= 799.479784131536
# differential_evolution step 11: f(x)= 682.8980649361016
# differential_evolution step 12: f(x)= 327.0844377947937
# differential_evolution step 13: f(x)= 184.2282337507498
# differential_evolution step 14: f(x)= 103.31455605556822
# differential_evolution step 15: f(x)= 44.15051925928605
# differential_evolution step 16: f(x)= 44.15051925928605
# differential_evolution step 17: f(x)= 44.15051925928605
# differential_evolution step 18: f(x)= 44.15051925928605
# differential_evolution step 19: f(x)= 44.15051925928605
# differential_evolution step 20: f(x)= 18.135867056283825
# differential_evolution step 21: f(x)= 18.135867056283825
# differential_evolution step 22: f(x)= 18.135867056283825
# differential_evolution step 23: f(x)= 18.135867056283825
# differential_evolution step 24: f(x)= 18.135867056283825
# differential_evolution step 25: f(x)= 18.135867056283825
# differential_evolution step 26: f(x)= 18.135867056283825
# differential_evolution step 27: f(x)= 18.135867056283825
# differential_evolution step 28: f(x)= 18.135867056283825
# differential_evolution step 29: f(x)= 18.135867056283825
# differential_evolution step 30: f(x)= 18.135867056283825
# differential_evolution step 31: f(x)= 13.517840023094154
# differential_evolution step 32: f(x)= 13.517840023094154
# differential_evolution step 33: f(x)= 7.158611415478621
# differential_evolution step 34: f(x)= 7.158611415478621
# differential_evolution step 35: f(x)= 7.158611415478621
# differential_evolution step 36: f(x)= 7.158611415478621
# differential_evolution step 37: f(x)= 7.158611415478621
# differential_evolution step 38: f(x)= 7.158611415478621
# differential_evolution step 39: f(x)= 7.158611415478621
# differential_evolution step 40: f(x)= 7.158611415478621
# differential_evolution step 41: f(x)= 7.158611415478621
# differential_evolution step 42: f(x)= 7.158611415478621
# differential_evolution step 43: f(x)= 7.158611415478621
# differential_evolution step 44: f(x)= 7.158611415478621
# differential_evolution step 45: f(x)= 5.169123741062359
# differential_evolution step 46: f(x)= 5.169123741062359
# differential_evolution step 47: f(x)= 5.169123741062359
# differential_evolution step 48: f(x)= 5.169123741062359
# differential_evolution step 49: f(x)= 5.169123741062359
# differential_evolution step 50: f(x)= 5.169123741062359
# differential_evolution step 51: f(x)= 5.169123741062359
# differential_evolution step 52: f(x)= 5.169123741062359
# differential_evolution step 53: f(x)= 5.169123741062359
# differential_evolution step 54: f(x)= 5.169123741062359
# differential_evolution step 55: f(x)= 5.169123741062359
# differential_evolution step 56: f(x)= 5.169123741062359
# differential_evolution step 57: f(x)= 5.169123741062359
# differential_evolution step 58: f(x)= 5.169123741062359
# differential_evolution step 59: f(x)= 5.169123741062359
# differential_evolution step 60: f(x)= 5.169123741062359
# differential_evolution step 61: f(x)= 5.169123741062359
# differential_evolution step 62: f(x)= 5.169123741062359
# differential_evolution step 63: f(x)= 5.169123741062359
# differential_evolution step 64: f(x)= 4.231656138398713
# differential_evolution step 65: f(x)= 4.231656138398713
# differential_evolution step 66: f(x)= 4.231656138398713
# differential_evolution step 67: f(x)= 4.231656138398713
# differential_evolution step 68: f(x)= 4.231656138398713
# differential_evolution step 69: f(x)= 4.231656138398713
# differential_evolution step 70: f(x)= 4.231656138398713
# differential_evolution step 71: f(x)= 4.231656138398713
# differential_evolution step 72: f(x)= 4.231656138398713
# differential_evolution step 73: f(x)= 4.231656138398713
# differential_evolution step 74: f(x)= 4.231656138398713
# differential_evolution step 75: f(x)= 4.231656138398713
# differential_evolution step 76: f(x)= 4.231656138398713
# differential_evolution step 77: f(x)= 4.231656138398713
# differential_evolution step 78: f(x)= 4.231656138398713
# differential_evolution step 79: f(x)= 4.231656138398713
# differential_evolution step 80: f(x)= 4.231656138398713
# differential_evolution step 81: f(x)= 3.0909224394395562
# differential_evolution step 82: f(x)= 3.0909224394395562
# differential_evolution step 83: f(x)= 3.0909224394395562
# differential_evolution step 84: f(x)= 3.0909224394395562
# differential_evolution step 85: f(x)= 3.0909224394395562
# differential_evolution step 86: f(x)= 3.0909224394395562
# differential_evolution step 87: f(x)= 3.0909224394395562
# differential_evolution step 88: f(x)= 2.573874559341758
# differential_evolution step 89: f(x)= 2.573874559341758
# differential_evolution step 90: f(x)= 2.573874559341758
# differential_evolution step 91: f(x)= 2.573874559341758
# differential_evolution step 92: f(x)= 2.573874559341758
# differential_evolution step 93: f(x)= 2.573874559341758
# differential_evolution step 94: f(x)= 2.573874559341758
# differential_evolution step 95: f(x)= 2.573874559341758
# differential_evolution step 96: f(x)= 2.573874559341758
# differential_evolution step 97: f(x)= 2.573874559341758
# differential_evolution step 98: f(x)= 2.573874559341758
# differential_evolution step 99: f(x)= 2.573874559341758
# differential_evolution step 100: f(x)= 2.573874559341758
# differential_evolution step 101: f(x)= 2.440664024642115
# differential_evolution step 102: f(x)= 2.0703662281605224
# differential_evolution step 103: f(x)= 1.8524520788740384
# differential_evolution step 104: f(x)= 1.8524520788740384
# differential_evolution step 105: f(x)= 1.8524520788740384
# differential_evolution step 106: f(x)= 1.8524520788740384
# differential_evolution step 107: f(x)= 1.8524520788740384
# differential_evolution step 108: f(x)= 1.5733039334335168
# differential_evolution step 109: f(x)= 1.5733039334335168
# differential_evolution step 110: f(x)= 1.5733039334335168
# differential_evolution step 111: f(x)= 1.5733039334335168
# differential_evolution step 112: f(x)= 1.5733039334335168
# differential_evolution step 113: f(x)= 1.5733039334335168
# differential_evolution step 114: f(x)= 1.368078734038024
# differential_evolution step 115: f(x)= 1.368078734038024
# differential_evolution step 116: f(x)= 1.368078734038024
# differential_evolution step 117: f(x)= 1.368078734038024
# differential_evolution step 118: f(x)= 1.368078734038024
# differential_evolution step 119: f(x)= 1.368078734038024
# differential_evolution step 120: f(x)= 1.368078734038024
# differential_evolution step 121: f(x)= 1.368078734038024
# differential_evolution step 122: f(x)= 1.3604389763387306
# differential_evolution step 123: f(x)= 1.3604389763387306
# differential_evolution step 124: f(x)= 1.3604389763387306
# differential_evolution step 125: f(x)= 1.3604389763387306
# differential_evolution step 126: f(x)= 1.3604389763387306
# differential_evolution step 127: f(x)= 1.3604389763387306
# differential_evolution step 128: f(x)= 1.3604389763387306
# differential_evolution step 129: f(x)= 1.3604389763387306
# differential_evolution step 130: f(x)= 1.3604389763387306
# differential_evolution step 131: f(x)= 1.3604389763387306
# differential_evolution step 132: f(x)= 1.3604389763387306
# differential_evolution step 133: f(x)= 1.3604389763387306
# differential_evolution step 134: f(x)= 1.3604389763387306
# differential_evolution step 135: f(x)= 1.3604389763387306
# differential_evolution step 136: f(x)= 1.3604389763387306
# differential_evolution step 137: f(x)= 1.336370582871645
# differential_evolution step 138: f(x)= 1.1860912821811276
# differential_evolution step 139: f(x)= 1.1860912821811276
# differential_evolution step 140: f(x)= 1.1724628495942873
# differential_evolution step 141: f(x)= 1.1724628495942873
# differential_evolution step 142: f(x)= 1.1074248993990352
# differential_evolution step 143: f(x)= 1.1074248993990352
# differential_evolution step 144: f(x)= 0.9444166252789471
# differential_evolution step 145: f(x)= 0.9444166252789471
# differential_evolution step 146: f(x)= 0.9444166252789471
# differential_evolution step 147: f(x)= 0.9444166252789471
# differential_evolution step 148: f(x)= 0.7983543966070603
# differential_evolution step 149: f(x)= 0.7037895883443909
# differential_evolution step 150: f(x)= 0.7037895883443909
# differential_evolution step 151: f(x)= 0.7037895883443909
# differential_evolution step 152: f(x)= 0.7037895883443909
# differential_evolution step 153: f(x)= 0.7037895883443909
# differential_evolution step 154: f(x)= 0.6622479534358782
# differential_evolution step 155: f(x)= 0.6622479534358782
# differential_evolution step 156: f(x)= 0.6622479534358782
# differential_evolution step 157: f(x)= 0.6622479534358782
# differential_evolution step 158: f(x)= 0.640398196152367
# differential_evolution step 159: f(x)= 0.640398196152367
# differential_evolution step 160: f(x)= 0.640398196152367
# differential_evolution step 161: f(x)= 0.640398196152367
# differential_evolution step 162: f(x)= 0.640398196152367
# differential_evolution step 163: f(x)= 0.640398196152367
# differential_evolution step 164: f(x)= 0.640398196152367
# differential_evolution step 165: f(x)= 0.640398196152367
# differential_evolution step 166: f(x)= 0.640398196152367
# differential_evolution step 167: f(x)= 0.640398196152367
# differential_evolution step 168: f(x)= 0.640398196152367
# differential_evolution step 169: f(x)= 0.640398196152367
# differential_evolution step 170: f(x)= 0.6330351654269591
# differential_evolution step 171: f(x)= 0.5963790136288027
# differential_evolution step 172: f(x)= 0.5963790136288027
# differential_evolution step 173: f(x)= 0.5963790136288027
# differential_evolution step 174: f(x)= 0.5963790136288027
# differential_evolution step 175: f(x)= 0.5963790136288027
# differential_evolution step 176: f(x)= 0.5963790136288027
# differential_evolution step 177: f(x)= 0.5963790136288027
# differential_evolution step 178: f(x)= 0.5963790136288027
# differential_evolution step 179: f(x)= 0.5963790136288027
# differential_evolution step 180: f(x)= 0.5963790136288027
# differential_evolution step 181: f(x)= 0.5963790136288027
# differential_evolution step 182: f(x)= 0.5963790136288027
# differential_evolution step 183: f(x)= 0.5963790136288027
# differential_evolution step 184: f(x)= 0.5963790136288027
# differential_evolution step 185: f(x)= 0.5776547747698075
# differential_evolution step 186: f(x)= 0.5450007693549398
# differential_evolution step 187: f(x)= 0.5450007693549398
# differential_evolution step 188: f(x)= 0.5450007693549398
# differential_evolution step 189: f(x)= 0.5391322097454866
# differential_evolution step 190: f(x)= 0.5391322097454866
# differential_evolution step 191: f(x)= 0.5391322097454866
# differential_evolution step 192: f(x)= 0.5391322097454866
# differential_evolution step 193: f(x)= 0.5391322097454866
# differential_evolution step 194: f(x)= 0.5391322097454866
# differential_evolution step 195: f(x)= 0.5391322097454866
# differential_evolution step 196: f(x)= 0.5236116398034323
# differential_evolution step 197: f(x)= 0.5236116398034323
# differential_evolution step 198: f(x)= 0.5236116398034323
# differential_evolution step 199: f(x)= 0.5236116398034323
# differential_evolution step 200: f(x)= 0.5236116398034323
# differential_evolution step 201: f(x)= 0.5236116398034323
# differential_evolution step 202: f(x)= 0.5236116398034323
# differential_evolution step 203: f(x)= 0.5236116398034323
# differential_evolution step 204: f(x)= 0.5236116398034323
# differential_evolution step 205: f(x)= 0.5236116398034323
# differential_evolution step 206: f(x)= 0.5202610621409831
# differential_evolution step 207: f(x)= 0.5202610621409831
# differential_evolution step 208: f(x)= 0.5144015510897244
# differential_evolution step 209: f(x)= 0.5144015510897244
# differential_evolution step 210: f(x)= 0.5144015510897244
# differential_evolution step 211: f(x)= 0.5144015510897244
# differential_evolution step 212: f(x)= 0.5144015510897244
# differential_evolution step 213: f(x)= 0.5144015510897244
# differential_evolution step 214: f(x)= 0.5114190598541692
# differential_evolution step 215: f(x)= 0.5114190598541692
# differential_evolution step 216: f(x)= 0.5114190598541692
# differential_evolution step 217: f(x)= 0.5080063022085012
# differential_evolution step 218: f(x)= 0.5080063022085012
# differential_evolution step 219: f(x)= 0.5080063022085012
# differential_evolution step 220: f(x)= 0.5080063022085012
# differential_evolution step 221: f(x)= 0.5077959869546212
# differential_evolution step 222: f(x)= 0.5077959869546212
# differential_evolution step 223: f(x)= 0.5033964371326947
# differential_evolution step 224: f(x)= 0.5033964371326947
# differential_evolution step 225: f(x)= 0.5033964371326947
# differential_evolution step 226: f(x)= 0.5033964371326947
# differential_evolution step 227: f(x)= 0.5033964371326947
# differential_evolution step 228: f(x)= 0.5033964371326947
# differential_evolution step 229: f(x)= 0.49832032624641953
# differential_evolution step 230: f(x)= 0.49832032624641953
# differential_evolution step 231: f(x)= 0.49832032624641953
# differential_evolution step 232: f(x)= 0.4953876134516593
# differential_evolution step 233: f(x)= 0.4953876134516593
# differential_evolution step 234: f(x)= 0.4953876134516593
# differential_evolution step 235: f(x)= 0.4953876134516593
# differential_evolution step 236: f(x)= 0.4953876134516593
# differential_evolution step 237: f(x)= 0.4953876134516593
# differential_evolution step 238: f(x)= 0.4953876134516593
# differential_evolution step 239: f(x)= 0.4953876134516593
# differential_evolution step 240: f(x)= 0.4953876134516593
# differential_evolution step 241: f(x)= 0.49523115462771056
# differential_evolution step 242: f(x)= 0.49523115462771056
# differential_evolution step 243: f(x)= 0.49523115462771056
# differential_evolution step 244: f(x)= 0.49523115462771056
# differential_evolution step 245: f(x)= 0.4847667339580556
# differential_evolution step 246: f(x)= 0.4847667339580556
# differential_evolution step 247: f(x)= 0.4847667339580556
# differential_evolution step 248: f(x)= 0.4847667339580556
# differential_evolution step 249: f(x)= 0.4847667339580556
# differential_evolution step 250: f(x)= 0.4847667339580556
# differential_evolution step 251: f(x)= 0.4847667339580556
# differential_evolution step 252: f(x)= 0.4847667339580556
# differential_evolution step 253: f(x)= 0.4847667339580556
# differential_evolution step 254: f(x)= 0.4847667339580556
# differential_evolution step 255: f(x)= 0.4847667339580556
# differential_evolution step 256: f(x)= 0.4847667339580556
# differential_evolution step 257: f(x)= 0.4847667339580556
# differential_evolution step 258: f(x)= 0.4847667339580556
# differential_evolution step 259: f(x)= 0.4797678844631231
# differential_evolution step 260: f(x)= 0.4797678844631231
# differential_evolution step 261: f(x)= 0.4797678844631231
# differential_evolution step 262: f(x)= 0.4797678844631231
# differential_evolution step 263: f(x)= 0.4797678844631231
# differential_evolution step 264: f(x)= 0.4797678844631231
# differential_evolution step 265: f(x)= 0.4797678844631231
# differential_evolution step 266: f(x)= 0.4797678844631231
# differential_evolution step 267: f(x)= 0.47733601261379416
# differential_evolution step 268: f(x)= 0.47733601261379416
# differential_evolution step 269: f(x)= 0.47733601261379416
# differential_evolution step 270: f(x)= 0.47733601261379416
# differential_evolution step 271: f(x)= 0.47733601261379416
# differential_evolution step 272: f(x)= 0.47733601261379416
# differential_evolution step 273: f(x)= 0.47733601261379416
# differential_evolution step 274: f(x)= 0.47733601261379416
# differential_evolution step 275: f(x)= 0.47733601261379416
# differential_evolution step 276: f(x)= 0.47733601261379416
# differential_evolution step 277: f(x)= 0.47733601261379416
# differential_evolution step 278: f(x)= 0.47733601261379416
# differential_evolution step 279: f(x)= 0.47733601261379416
# differential_evolution step 280: f(x)= 0.47733601261379416
# differential_evolution step 281: f(x)= 0.47733601261379416
# differential_evolution step 282: f(x)= 0.4750113475189896
# differential_evolution step 283: f(x)= 0.4750113475189896
# differential_evolution step 284: f(x)= 0.4750113475189896
# differential_evolution step 285: f(x)= 0.4750113475189896
# differential_evolution step 286: f(x)= 0.4750113475189896
# differential_evolution step 287: f(x)= 0.4750113475189896
# differential_evolution step 288: f(x)= 0.4750113475189896
# differential_evolution step 289: f(x)= 0.4745938111693048
# differential_evolution step 290: f(x)= 0.4745938111693048
# differential_evolution step 291: f(x)= 0.4745938111693048
# differential_evolution step 292: f(x)= 0.47384058977587146
# differential_evolution step 293: f(x)= 0.47384058977587146
# differential_evolution step 294: f(x)= 0.47384058977587146
# differential_evolution step 295: f(x)= 0.47384058977587146
# differential_evolution step 296: f(x)= 0.47384058977587146
# differential_evolution step 297: f(x)= 0.47384058977587146
# differential_evolution step 298: f(x)= 0.47216957477161486
# differential_evolution step 299: f(x)= 0.47216957477161486
# differential_evolution step 300: f(x)= 0.47216957477161486
# differential_evolution step 301: f(x)= 0.47216957477161486
# differential_evolution step 302: f(x)= 0.47216957477161486
# differential_evolution step 303: f(x)= 0.47216957477161486
# differential_evolution step 304: f(x)= 0.47216957477161486
# differential_evolution step 305: f(x)= 0.47216957477161486
# differential_evolution step 306: f(x)= 0.47216957477161486
# differential_evolution step 307: f(x)= 0.47216957477161486
# differential_evolution step 308: f(x)= 0.47216957477161486
# differential_evolution step 309: f(x)= 0.47216957477161486
# differential_evolution step 310: f(x)= 0.47216957477161486
# differential_evolution step 311: f(x)= 0.4718487971341698
# differential_evolution step 312: f(x)= 0.4718487971341698
# differential_evolution step 313: f(x)= 0.4718487971341698
# differential_evolution step 314: f(x)= 0.4718487971341698
# differential_evolution step 315: f(x)= 0.4718487971341698
# differential_evolution step 316: f(x)= 0.4718487971341698
# differential_evolution step 317: f(x)= 0.4718487971341698
# differential_evolution step 318: f(x)= 0.4718487971341698
# differential_evolution step 319: f(x)= 0.4718487971341698
# differential_evolution step 320: f(x)= 0.4718487971341698
# differential_evolution step 321: f(x)= 0.4718487971341698
# differential_evolution step 322: f(x)= 0.4718487971341698
# differential_evolution step 323: f(x)= 0.4718487971341698
# differential_evolution step 324: f(x)= 0.4718487971341698
# differential_evolution step 325: f(x)= 0.4718487971341698
# differential_evolution step 326: f(x)= 0.4715995982404836
# differential_evolution step 327: f(x)= 0.4715995982404836
# differential_evolution step 328: f(x)= 0.4715995982404836
# differential_evolution step 329: f(x)= 0.47147983368346
# differential_evolution step 330: f(x)= 0.47147983368346
# differential_evolution step 331: f(x)= 0.47147983368346
# differential_evolution step 332: f(x)= 0.47147983368346
# differential_evolution step 333: f(x)= 0.47147983368346
# differential_evolution step 334: f(x)= 0.47147983368346
# differential_evolution step 335: f(x)= 0.47147983368346
# differential_evolution step 336: f(x)= 0.47147983368346
# differential_evolution step 337: f(x)= 0.47147983368346
# differential_evolution step 338: f(x)= 0.47147983368346
# differential_evolution step 339: f(x)= 0.47147983368346
# differential_evolution step 340: f(x)= 0.47147983368346
# differential_evolution step 341: f(x)= 0.47147983368346
# differential_evolution step 342: f(x)= 0.47147983368346
# differential_evolution step 343: f(x)= 0.47147983368346
# differential_evolution step 344: f(x)= 0.47147983368346
# differential_evolution step 345: f(x)= 0.47147983368346
# differential_evolution step 346: f(x)= 0.47147983368346
# differential_evolution step 347: f(x)= 0.47109778480330644
# differential_evolution step 348: f(x)= 0.47109778480330644
# differential_evolution step 349: f(x)= 0.4701091485912821
# differential_evolution step 350: f(x)= 0.4701091485912821
# differential_evolution step 351: f(x)= 0.4701091485912821
# differential_evolution step 352: f(x)= 0.4701091485912821
# differential_evolution step 353: f(x)= 0.4701091485912821
# differential_evolution step 354: f(x)= 0.4701091485912821
# differential_evolution step 355: f(x)= 0.4701091485912821
# differential_evolution step 356: f(x)= 0.4701091485912821
# differential_evolution step 357: f(x)= 0.4701091485912821
# differential_evolution step 358: f(x)= 0.4701091485912821
# differential_evolution step 359: f(x)= 0.4701091485912821
# differential_evolution step 360: f(x)= 0.4701091485912821
# differential_evolution step 361: f(x)= 0.4701091485912821
# differential_evolution step 362: f(x)= 0.4701091485912821
# differential_evolution step 363: f(x)= 0.46963906257595134
# differential_evolution step 364: f(x)= 0.46963906257595134
# differential_evolution step 365: f(x)= 0.46963906257595134
# differential_evolution step 366: f(x)= 0.46963906257595134
# differential_evolution step 367: f(x)= 0.46963906257595134
# differential_evolution step 368: f(x)= 0.46963906257595134
# differential_evolution step 369: f(x)= 0.46963906257595134
# differential_evolution step 370: f(x)= 0.4694399595079742
# differential_evolution step 371: f(x)= 0.4694399595079742
# differential_evolution step 372: f(x)= 0.46912553288068504
# differential_evolution step 373: f(x)= 0.46912553288068504
# differential_evolution step 374: f(x)= 0.46912553288068504
# differential_evolution step 375: f(x)= 0.46912553288068504
# differential_evolution step 376: f(x)= 0.4691182819906883
# differential_evolution step 377: f(x)= 0.4691182819906883
# differential_evolution step 378: f(x)= 0.4691182819906883
# differential_evolution step 379: f(x)= 0.469117615737858
# differential_evolution step 380: f(x)= 0.469117615737858
# differential_evolution step 381: f(x)= 0.4687551951494827
# differential_evolution step 382: f(x)= 0.4687551951494827
# differential_evolution step 383: f(x)= 0.4686689128005198
# differential_evolution step 384: f(x)= 0.4686689128005198
# differential_evolution step 385: f(x)= 0.4686689128005198
# differential_evolution step 386: f(x)= 0.4686689128005198
# differential_evolution step 387: f(x)= 0.4686689128005198
# differential_evolution step 388: f(x)= 0.4686689128005198
# differential_evolution step 389: f(x)= 0.4686689128005198
# differential_evolution step 390: f(x)= 0.4686689128005198
# differential_evolution step 391: f(x)= 0.4686689128005198
# differential_evolution step 392: f(x)= 0.4686689128005198
# differential_evolution step 393: f(x)= 0.4686689128005198
# differential_evolution step 394: f(x)= 0.4686689128005198
# differential_evolution step 395: f(x)= 0.4686464727023064
# differential_evolution step 396: f(x)= 0.4686464727023064
# differential_evolution step 397: f(x)= 0.4686464727023064
# differential_evolution step 398: f(x)= 0.4686464727023064
# differential_evolution step 399: f(x)= 0.4686464727023064
# differential_evolution step 400: f(x)= 0.46863163839418237
# differential_evolution step 401: f(x)= 0.4680248596580302
# differential_evolution step 402: f(x)= 0.4680248596580302
# differential_evolution step 403: f(x)= 0.4680248596580302
# differential_evolution step 404: f(x)= 0.4680248596580302
# differential_evolution step 405: f(x)= 0.4680248596580302
# differential_evolution step 406: f(x)= 0.4680248596580302
# differential_evolution step 407: f(x)= 0.4680248596580302
# differential_evolution step 408: f(x)= 0.4680248596580302
# differential_evolution step 409: f(x)= 0.4679578094172989
# differential_evolution step 410: f(x)= 0.4679578094172989
# differential_evolution step 411: f(x)= 0.4679578094172989
# differential_evolution step 412: f(x)= 0.4679578094172989
# differential_evolution step 413: f(x)= 0.4679578094172989
# differential_evolution step 414: f(x)= 0.4679578094172989
# differential_evolution step 415: f(x)= 0.4679578094172989
# differential_evolution step 416: f(x)= 0.4679578094172989
# differential_evolution step 417: f(x)= 0.4679578094172989
# differential_evolution step 418: f(x)= 0.4679578094172989
# differential_evolution step 419: f(x)= 0.4679578094172989
# differential_evolution step 420: f(x)= 0.4679578094172989
# differential_evolution step 421: f(x)= 0.4679578094172989
# differential_evolution step 422: f(x)= 0.46788616955529144
# differential_evolution step 423: f(x)= 0.46788616955529144
# differential_evolution step 424: f(x)= 0.46788616955529144
# differential_evolution step 425: f(x)= 0.46788616955529144
# differential_evolution step 426: f(x)= 0.46788616955529144
# differential_evolution step 427: f(x)= 0.46788616955529144
# differential_evolution step 428: f(x)= 0.46788616955529144
# differential_evolution step 429: f(x)= 0.46788616955529144
# differential_evolution step 430: f(x)= 0.46788616955529144
# differential_evolution step 431: f(x)= 0.46788616955529144
# differential_evolution step 432: f(x)= 0.4676051756954069
# differential_evolution step 433: f(x)= 0.4676051756954069
# differential_evolution step 434: f(x)= 0.4676051756954069
# differential_evolution step 435: f(x)= 0.4676051756954069
# differential_evolution step 436: f(x)= 0.4676051756954069
# differential_evolution step 437: f(x)= 0.4675972587134561
# differential_evolution step 438: f(x)= 0.4675972587134561
# differential_evolution step 439: f(x)= 0.4675972587134561
# differential_evolution step 440: f(x)= 0.4675972587134561
# differential_evolution step 441: f(x)= 0.4675972587134561
# differential_evolution step 442: f(x)= 0.4675972587134561
# differential_evolution step 443: f(x)= 0.4675972587134561
# differential_evolution step 444: f(x)= 0.4675972587134561
# differential_evolution step 445: f(x)= 0.4675972587134561
# differential_evolution step 446: f(x)= 0.4675972587134561
# differential_evolution step 447: f(x)= 0.4675972587134561
# differential_evolution step 448: f(x)= 0.4675972587134561
# differential_evolution step 449: f(x)= 0.4675972587134561
# differential_evolution step 450: f(x)= 0.4675972587134561
# differential_evolution step 451: f(x)= 0.4675972587134561
# differential_evolution step 452: f(x)= 0.4675972587134561
# differential_evolution step 453: f(x)= 0.4675972587134561
# differential_evolution step 454: f(x)= 0.4675972587134561
# differential_evolution step 455: f(x)= 0.4675972587134561
# differential_evolution step 456: f(x)= 0.4675972587134561
# differential_evolution step 457: f(x)= 0.4675972587134561
# differential_evolution step 458: f(x)= 0.4675972587134561
# differential_evolution step 459: f(x)= 0.4675972587134561
# differential_evolution step 460: f(x)= 0.4675972587134561
# differential_evolution step 461: f(x)= 0.4675972587134561
# differential_evolution step 462: f(x)= 0.4675972587134561
# differential_evolution step 463: f(x)= 0.4675972587134561
# differential_evolution step 464: f(x)= 0.4675972587134561
# differential_evolution step 465: f(x)= 0.4675972587134561
# differential_evolution step 466: f(x)= 0.4675972587134561
# differential_evolution step 467: f(x)= 0.4675972587134561
# differential_evolution step 468: f(x)= 0.4675972587134561
# differential_evolution step 469: f(x)= 0.4675972587134561
# differential_evolution step 470: f(x)= 0.4675972587134561
# differential_evolution step 471: f(x)= 0.4675972587134561
# differential_evolution step 472: f(x)= 0.4675972587134561
# differential_evolution step 473: f(x)= 0.4675972587134561
# differential_evolution step 474: f(x)= 0.4675972587134561
# differential_evolution step 475: f(x)= 0.4674551172874789
# differential_evolution step 476: f(x)= 0.4674551172874789
# differential_evolution step 477: f(x)= 0.4674551172874789
# differential_evolution step 478: f(x)= 0.4674551172874789
# differential_evolution step 479: f(x)= 0.4674551172874789
# differential_evolution step 480: f(x)= 0.4674551172874789
# differential_evolution step 481: f(x)= 0.4674551172874789
# differential_evolution step 482: f(x)= 0.4674551172874789
# differential_evolution step 483: f(x)= 0.4674551172874789
# differential_evolution step 484: f(x)= 0.4674551172874789
# differential_evolution step 485: f(x)= 0.4674551172874789
# differential_evolution step 486: f(x)= 0.4674551172874789
# differential_evolution step 487: f(x)= 0.4674551172874789
# differential_evolution step 488: f(x)= 0.4674551172874789
# differential_evolution step 489: f(x)= 0.4674551172874789
# differential_evolution step 490: f(x)= 0.4674551172874789
# differential_evolution step 491: f(x)= 0.4674551172874789
# differential_evolution step 492: f(x)= 0.4674551172874789
# differential_evolution step 493: f(x)= 0.4674551172874789
# differential_evolution step 494: f(x)= 0.4674551172874789
# differential_evolution step 495: f(x)= 0.4674551172874789
# differential_evolution step 496: f(x)= 0.4674551172874789
# differential_evolution step 497: f(x)= 0.4674551172874789
# differential_evolution step 498: f(x)= 0.4674551172874789
# differential_evolution step 499: f(x)= 0.4674551172874789
# differential_evolution step 500: f(x)= 0.4674551172874789
# differential_evolution step 501: f(x)= 0.4674551172874789
# differential_evolution step 502: f(x)= 0.4674551172874789
# differential_evolution step 503: f(x)= 0.4674551172874789
# differential_evolution step 504: f(x)= 0.4674551172874789
# differential_evolution step 505: f(x)= 0.4674551172874789
# differential_evolution step 506: f(x)= 0.4674551172874789
# differential_evolution step 507: f(x)= 0.4674551172874789
# differential_evolution step 508: f(x)= 0.4674551172874789
# differential_evolution step 509: f(x)= 0.4674551172874789
# differential_evolution step 510: f(x)= 0.4674551172874789
# differential_evolution step 511: f(x)= 0.4674551172874789
# differential_evolution step 512: f(x)= 0.4674551172874789
# differential_evolution step 513: f(x)= 0.4674054156829718
# differential_evolution step 514: f(x)= 0.4674054156829718
# differential_evolution step 515: f(x)= 0.4674054156829718
# differential_evolution step 516: f(x)= 0.4674054156829718
# differential_evolution step 517: f(x)= 0.4674054156829718
# differential_evolution step 518: f(x)= 0.4674054156829718
# differential_evolution step 519: f(x)= 0.4674054156829718
# differential_evolution step 520: f(x)= 0.4674054156829718
# differential_evolution step 521: f(x)= 0.4674054156829718
# differential_evolution step 522: f(x)= 0.4674054156829718
# differential_evolution step 523: f(x)= 0.4674054156829718
# differential_evolution step 524: f(x)= 0.4674054156829718
# differential_evolution step 525: f(x)= 0.4674054156829718
# differential_evolution step 526: f(x)= 0.4674054156829718
# differential_evolution step 527: f(x)= 0.4674054156829718
# differential_evolution step 528: f(x)= 0.4674054156829718
# differential_evolution step 529: f(x)= 0.4674054156829718
# differential_evolution step 530: f(x)= 0.4674054156829718
# differential_evolution step 531: f(x)= 0.4674054156829718
# differential_evolution step 532: f(x)= 0.4674054156829718
# differential_evolution step 533: f(x)= 0.4674054156829718
# differential_evolution step 534: f(x)= 0.4674054156829718
# differential_evolution step 535: f(x)= 0.4674054156829718
# differential_evolution step 536: f(x)= 0.4674054156829718
# differential_evolution step 537: f(x)= 0.4674054156829718
# differential_evolution step 538: f(x)= 0.4674054156829718
# differential_evolution step 539: f(x)= 0.4674054156829718
# differential_evolution step 540: f(x)= 0.46736766170470107
# differential_evolution step 541: f(x)= 0.46736766170470107
# differential_evolution step 542: f(x)= 0.46736766170470107
# differential_evolution step 543: f(x)= 0.46736766170470107
# differential_evolution step 544: f(x)= 0.46736766170470107
# differential_evolution step 545: f(x)= 0.46736766170470107
# differential_evolution step 546: f(x)= 0.4673419841541547
# differential_evolution step 547: f(x)= 0.4673419841541547
# differential_evolution step 548: f(x)= 0.4673419841541547
# differential_evolution step 549: f(x)= 0.4673419841541547
# differential_evolution step 550: f(x)= 0.4673419841541547
# differential_evolution step 551: f(x)= 0.4673419841541547
# differential_evolution step 552: f(x)= 0.4673419841541547
# differential_evolution step 553: f(x)= 0.4673419841541547
# differential_evolution step 554: f(x)= 0.4673419841541547
# differential_evolution step 555: f(x)= 0.4673419841541547
# differential_evolution step 556: f(x)= 0.4673419841541547
# differential_evolution step 557: f(x)= 0.4673419841541547
# differential_evolution step 558: f(x)= 0.4673419841541547
# differential_evolution step 559: f(x)= 0.4673419841541547
# differential_evolution step 560: f(x)= 0.4673419841541547
# differential_evolution step 561: f(x)= 0.4673419841541547
# differential_evolution step 562: f(x)= 0.4673419841541547
# differential_evolution step 563: f(x)= 0.4673419841541547
# differential_evolution step 564: f(x)= 0.4673419841541547
# differential_evolution step 565: f(x)= 0.4673419841541547
# differential_evolution step 566: f(x)= 0.4673419841541547
# differential_evolution step 567: f(x)= 0.4673419841541547
# differential_evolution step 568: f(x)= 0.4673419841541547
# differential_evolution step 569: f(x)= 0.4673419841541547
# differential_evolution step 570: f(x)= 0.4673419841541547
# differential_evolution step 571: f(x)= 0.4673419841541547
# differential_evolution step 572: f(x)= 0.4673419841541547
# differential_evolution step 573: f(x)= 0.46733856818610503
# differential_evolution step 574: f(x)= 0.46733856818610503
# differential_evolution step 575: f(x)= 0.46733856818610503
# differential_evolution step 576: f(x)= 0.46733856818610503
# differential_evolution step 577: f(x)= 0.46733856818610503
# differential_evolution step 578: f(x)= 0.46733856818610503
# differential_evolution step 579: f(x)= 0.4673308136240775
# differential_evolution step 580: f(x)= 0.4673308136240775
# differential_evolution step 581: f(x)= 0.4673308136240775
# differential_evolution step 582: f(x)= 0.4673308136240775
# differential_evolution step 583: f(x)= 0.4673308136240775
# differential_evolution step 584: f(x)= 0.4673308136240775
# differential_evolution step 585: f(x)= 0.4673308136240775
# differential_evolution step 586: f(x)= 0.4673308136240775
# differential_evolution step 587: f(x)= 0.4673308136240775
# differential_evolution step 588: f(x)= 0.4673308136240775
# differential_evolution step 589: f(x)= 0.4673308136240775
# differential_evolution step 590: f(x)= 0.4673308136240775
# differential_evolution step 591: f(x)= 0.4673308136240775
# differential_evolution step 592: f(x)= 0.4673308136240775
# differential_evolution step 593: f(x)= 0.4673308136240775
# differential_evolution step 594: f(x)= 0.4673308136240775
# differential_evolution step 595: f(x)= 0.4673308136240775
# differential_evolution step 596: f(x)= 0.4673308136240775
# differential_evolution step 597: f(x)= 0.4673308136240775
# differential_evolution step 598: f(x)= 0.46732566386089724
# differential_evolution step 599: f(x)= 0.46732566386089724
# differential_evolution step 600: f(x)= 0.46732566386089724
# differential_evolution step 601: f(x)= 0.46732566386089724
# differential_evolution step 602: f(x)= 0.46732566386089724
# differential_evolution step 603: f(x)= 0.46732566386089724
# differential_evolution step 604: f(x)= 0.46732566386089724
# differential_evolution step 605: f(x)= 0.46732130199123545
# differential_evolution step 606: f(x)= 0.46732130199123545
# differential_evolution step 607: f(x)= 0.46732130199123545
# differential_evolution step 608: f(x)= 0.4673204886623636
# differential_evolution step 609: f(x)= 0.46730472451214716
# differential_evolution step 610: f(x)= 0.46730472451214716
# differential_evolution step 611: f(x)= 0.46730472451214716
# differential_evolution step 612: f(x)= 0.46730472451214716
# differential_evolution step 613: f(x)= 0.4673037718889761
# differential_evolution step 614: f(x)= 0.4673037718889761
# differential_evolution step 615: f(x)= 0.4673037718889761
# differential_evolution step 616: f(x)= 0.46730257168266615
# differential_evolution step 617: f(x)= 0.46730257168266615
# differential_evolution step 618: f(x)= 0.46730257168266615
# differential_evolution step 619: f(x)= 0.46730257168266615
# differential_evolution step 620: f(x)= 0.46730257168266615
# differential_evolution step 621: f(x)= 0.46730257168266615
# differential_evolution step 622: f(x)= 0.46730257168266615
# differential_evolution step 623: f(x)= 0.46730257168266615
# differential_evolution step 624: f(x)= 0.46730257168266615
# differential_evolution step 625: f(x)= 0.46730257168266615
# differential_evolution step 626: f(x)= 0.46730257168266615
# differential_evolution step 627: f(x)= 0.46729681680143687
# differential_evolution step 628: f(x)= 0.46729681680143687
# differential_evolution step 629: f(x)= 0.46729681680143687
# differential_evolution step 630: f(x)= 0.46729681680143687
# differential_evolution step 631: f(x)= 0.46729681680143687
# differential_evolution step 632: f(x)= 0.46729681680143687
# differential_evolution step 633: f(x)= 0.46729681680143687
# differential_evolution step 634: f(x)= 0.46729681680143687
# differential_evolution step 635: f(x)= 0.46729681680143687
# differential_evolution step 636: f(x)= 0.46729681680143687
# differential_evolution step 637: f(x)= 0.46729681680143687
# differential_evolution step 638: f(x)= 0.46729681680143687
# differential_evolution step 639: f(x)= 0.46729681680143687
# differential_evolution step 640: f(x)= 0.46729681680143687
# differential_evolution step 641: f(x)= 0.46729681680143687
# differential_evolution step 642: f(x)= 0.46729681680143687
# differential_evolution step 643: f(x)= 0.46729681680143687
# differential_evolution step 644: f(x)= 0.46729681680143687
# differential_evolution step 645: f(x)= 0.46729681680143687
# differential_evolution step 646: f(x)= 0.46729681680143687
# differential_evolution step 647: f(x)= 0.46729681680143687
# differential_evolution step 648: f(x)= 0.46729681680143687
# differential_evolution step 649: f(x)= 0.46729681680143687
# differential_evolution step 650: f(x)= 0.46729681680143687
# differential_evolution step 651: f(x)= 0.46729681680143687
# differential_evolution step 652: f(x)= 0.46729681680143687
# differential_evolution step 653: f(x)= 0.46729681680143687
# differential_evolution step 654: f(x)= 0.46729681680143687
# differential_evolution step 655: f(x)= 0.46729681680143687
# differential_evolution step 656: f(x)= 0.46729681680143687
# differential_evolution step 657: f(x)= 0.46729681680143687
# differential_evolution step 658: f(x)= 0.4672936190030334
# differential_evolution step 659: f(x)= 0.4672936190030334
# differential_evolution step 660: f(x)= 0.4672936190030334
# differential_evolution step 661: f(x)= 0.4672936190030334
# differential_evolution step 662: f(x)= 0.4672936190030334
# differential_evolution step 663: f(x)= 0.4672936190030334
# differential_evolution step 664: f(x)= 0.4672936190030334
# differential_evolution step 665: f(x)= 0.4672900989567212
# differential_evolution step 666: f(x)= 0.46728365326312665
# differential_evolution step 667: f(x)= 0.46728365326312665
# differential_evolution step 668: f(x)= 0.46728365326312665
# differential_evolution step 669: f(x)= 0.46728365326312665
# differential_evolution step 670: f(x)= 0.46728365326312665
# differential_evolution step 671: f(x)= 0.46728365326312665
# differential_evolution step 672: f(x)= 0.4672829083504249
# differential_evolution step 673: f(x)= 0.4672829083504249
# differential_evolution step 674: f(x)= 0.4672829083504249
# differential_evolution step 675: f(x)= 0.46728256869045476
# differential_evolution step 676: f(x)= 0.467282039968983
# differential_evolution step 677: f(x)= 0.467282039968983
# differential_evolution step 678: f(x)= 0.467282039968983
# differential_evolution step 679: f(x)= 0.467282039968983
# differential_evolution step 680: f(x)= 0.467282039968983
# differential_evolution step 681: f(x)= 0.467282039968983
# differential_evolution step 682: f(x)= 0.4672709701803399
# differential_evolution step 683: f(x)= 0.4672709701803399
# differential_evolution step 684: f(x)= 0.4672709701803399
# differential_evolution step 685: f(x)= 0.4672709701803399
# differential_evolution step 686: f(x)= 0.4672709701803399
# differential_evolution step 687: f(x)= 0.4672709701803399
# differential_evolution step 688: f(x)= 0.4672709701803399
# differential_evolution step 689: f(x)= 0.4672709701803399
# differential_evolution step 690: f(x)= 0.4672709701803399
# differential_evolution step 691: f(x)= 0.4672709701803399
# differential_evolution step 692: f(x)= 0.4672709701803399
# differential_evolution step 693: f(x)= 0.4672709701803399
# differential_evolution step 694: f(x)= 0.4672709701803399
# differential_evolution step 695: f(x)= 0.4672709701803399
# differential_evolution step 696: f(x)= 0.4672709701803399
# differential_evolution step 697: f(x)= 0.467270034999491
# differential_evolution step 698: f(x)= 0.467270034999491
# differential_evolution step 699: f(x)= 0.467270034999491
# differential_evolution step 700: f(x)= 0.467270034999491
# differential_evolution step 701: f(x)= 0.467270034999491
# differential_evolution step 702: f(x)= 0.467270034999491
# differential_evolution step 703: f(x)= 0.46726881874728776
# differential_evolution step 704: f(x)= 0.46726881874728776
# differential_evolution step 705: f(x)= 0.46726881874728776
# differential_evolution step 706: f(x)= 0.46726881874728776
# differential_evolution step 707: f(x)= 0.46726881874728776
# differential_evolution step 708: f(x)= 0.46726881874728776
# differential_evolution step 709: f(x)= 0.46726881874728776
# differential_evolution step 710: f(x)= 0.46726881874728776
# differential_evolution step 711: f(x)= 0.46726881874728776
# differential_evolution step 712: f(x)= 0.46726881874728776
# differential_evolution step 713: f(x)= 0.46726881874728776
# differential_evolution step 714: f(x)= 0.46726881874728776
# differential_evolution step 715: f(x)= 0.46726881874728776
# differential_evolution step 716: f(x)= 0.46726881874728776
# differential_evolution step 717: f(x)= 0.46726881874728776
# differential_evolution step 718: f(x)= 0.46726881874728776
# differential_evolution step 719: f(x)= 0.46726881874728776
# differential_evolution step 720: f(x)= 0.46726881874728776
# differential_evolution step 721: f(x)= 0.46726881874728776
# differential_evolution step 722: f(x)= 0.46726881874728776
# differential_evolution step 723: f(x)= 0.46726881874728776
# differential_evolution step 724: f(x)= 0.46726881874728776
# differential_evolution step 725: f(x)= 0.46726881874728776
# differential_evolution step 726: f(x)= 0.46726881874728776
# differential_evolution step 727: f(x)= 0.46726881874728776
# differential_evolution step 728: f(x)= 0.46726881874728776
# differential_evolution step 729: f(x)= 0.4672674528833183
# differential_evolution step 730: f(x)= 0.46726546282037107
# differential_evolution step 731: f(x)= 0.46726546282037107
# differential_evolution step 732: f(x)= 0.46726449364341655
# differential_evolution step 733: f(x)= 0.46726449364341655
# differential_evolution step 734: f(x)= 0.46726449364341655
# differential_evolution step 735: f(x)= 0.46726449364341655
# differential_evolution step 736: f(x)= 0.46726449364341655
# differential_evolution step 737: f(x)= 0.46726449364341655
# differential_evolution step 738: f(x)= 0.46726449364341655
# differential_evolution step 739: f(x)= 0.46726449364341655
# differential_evolution step 740: f(x)= 0.46726449364341655
# differential_evolution step 741: f(x)= 0.46726449364341655
# differential_evolution step 742: f(x)= 0.46726449364341655
# differential_evolution step 743: f(x)= 0.46726449364341655
# differential_evolution step 744: f(x)= 0.46726449364341655
# differential_evolution step 745: f(x)= 0.4672631448142888
# differential_evolution step 746: f(x)= 0.4672631448142888
# differential_evolution step 747: f(x)= 0.4672631448142888
# differential_evolution step 748: f(x)= 0.4672631448142888
# differential_evolution step 749: f(x)= 0.46726269972893253
# differential_evolution step 750: f(x)= 0.46726269972893253
# differential_evolution step 751: f(x)= 0.4672620782501612
# differential_evolution step 752: f(x)= 0.46726079977413515
# differential_evolution step 753: f(x)= 0.46726079977413515
# differential_evolution step 754: f(x)= 0.46726079977413515
# differential_evolution step 755: f(x)= 0.4672548691973667
# differential_evolution step 756: f(x)= 0.4672506433524085
# differential_evolution step 757: f(x)= 0.4672506433524085
# differential_evolution step 758: f(x)= 0.4672506433524085
# differential_evolution step 759: f(x)= 0.4672506433524085
# differential_evolution step 760: f(x)= 0.46724851994379585
# differential_evolution step 761: f(x)= 0.46724851994379585
# differential_evolution step 762: f(x)= 0.46724851994379585
# differential_evolution step 763: f(x)= 0.46724851994379585
# differential_evolution step 764: f(x)= 0.46724851994379585
# differential_evolution step 765: f(x)= 0.46724851994379585
# differential_evolution step 766: f(x)= 0.46724851994379585
# differential_evolution step 767: f(x)= 0.46724851994379585
# differential_evolution step 768: f(x)= 0.46724851994379585
# differential_evolution step 769: f(x)= 0.46724851994379585
# differential_evolution step 770: f(x)= 0.46724851994379585
# differential_evolution step 771: f(x)= 0.46724851994379585
# differential_evolution step 772: f(x)= 0.46724851994379585
# differential_evolution step 773: f(x)= 0.46724851994379585
# differential_evolution step 774: f(x)= 0.46724851994379585
# differential_evolution step 775: f(x)= 0.46724851994379585
# differential_evolution step 776: f(x)= 0.46724851994379585
# differential_evolution step 777: f(x)= 0.46724851994379585
# differential_evolution step 778: f(x)= 0.46724851994379585
# differential_evolution step 779: f(x)= 0.46724851994379585
# differential_evolution step 780: f(x)= 0.4672474242837955
# differential_evolution step 781: f(x)= 0.46724706749440464
# differential_evolution step 782: f(x)= 0.46724706749440464
# differential_evolution step 783: f(x)= 0.46724706749440464
# differential_evolution step 784: f(x)= 0.46724706749440464
# differential_evolution step 785: f(x)= 0.46724626220726695
# differential_evolution step 786: f(x)= 0.46724480709461214
# differential_evolution step 787: f(x)= 0.4672411168817211
# differential_evolution step 788: f(x)= 0.4672411168817211
# differential_evolution step 789: f(x)= 0.4672411168817211
# differential_evolution step 790: f(x)= 0.4672408198772265
# differential_evolution step 791: f(x)= 0.46723510141751984
# differential_evolution step 792: f(x)= 0.46723493016695905
# differential_evolution step 793: f(x)= 0.46723493016695905
# differential_evolution step 794: f(x)= 0.46723493016695905
# differential_evolution step 795: f(x)= 0.46723493016695905
# differential_evolution step 796: f(x)= 0.46723493016695905
# differential_evolution step 797: f(x)= 0.46723493016695905
# differential_evolution step 798: f(x)= 0.46723493016695905
# differential_evolution step 799: f(x)= 0.4672317743237416
# differential_evolution step 800: f(x)= 0.4672317743237416
# differential_evolution step 801: f(x)= 0.4672317743237416
# differential_evolution step 802: f(x)= 0.46723171304532524
# differential_evolution step 803: f(x)= 0.46723171304532524
# differential_evolution step 804: f(x)= 0.46723171304532524
# differential_evolution step 805: f(x)= 0.4672215950991256
# differential_evolution step 806: f(x)= 0.46721610838336936
# differential_evolution step 807: f(x)= 0.46721610838336936
# differential_evolution step 808: f(x)= 0.46721610838336936
# differential_evolution step 809: f(x)= 0.46721610838336936
# differential_evolution step 810: f(x)= 0.46721610838336936
# differential_evolution step 811: f(x)= 0.46721610838336936
# differential_evolution step 812: f(x)= 0.46721610838336936
# differential_evolution step 813: f(x)= 0.46721610838336936
# differential_evolution step 814: f(x)= 0.46721610838336936
# differential_evolution step 815: f(x)= 0.46721610838336936
# differential_evolution step 816: f(x)= 0.46721610838336936
# differential_evolution step 817: f(x)= 0.46721610838336936
# differential_evolution step 818: f(x)= 0.46720866727243576
# differential_evolution step 819: f(x)= 0.46720866727243576
# differential_evolution step 820: f(x)= 0.46720866727243576
# differential_evolution step 821: f(x)= 0.46720866727243576
# differential_evolution step 822: f(x)= 0.46720866727243576
# differential_evolution step 823: f(x)= 0.46720866727243576
# differential_evolution step 824: f(x)= 0.46720866727243576
# differential_evolution step 825: f(x)= 0.46720619791475476
# differential_evolution step 826: f(x)= 0.46720619791475476
# differential_evolution step 827: f(x)= 0.4672035669267539
# differential_evolution step 828: f(x)= 0.46719574543265924
# differential_evolution step 829: f(x)= 0.46719574543265924
# differential_evolution step 830: f(x)= 0.46719574543265924
# differential_evolution step 831: f(x)= 0.4671929839842755
# differential_evolution step 832: f(x)= 0.4671929839842755
# differential_evolution step 833: f(x)= 0.4671912642959494
# differential_evolution step 834: f(x)= 0.4671878513584661
# differential_evolution step 835: f(x)= 0.4671878513584661
# differential_evolution step 836: f(x)= 0.4671864675074165
# differential_evolution step 837: f(x)= 0.4671864675074165
# differential_evolution step 838: f(x)= 0.4671864675074165
# differential_evolution step 839: f(x)= 0.4671864675074165
# differential_evolution step 840: f(x)= 0.4671864675074165
# differential_evolution step 841: f(x)= 0.4671864675074165
# differential_evolution step 842: f(x)= 0.4671860209465061
# differential_evolution step 843: f(x)= 0.4671860209465061
# differential_evolution step 844: f(x)= 0.4671860209465061
# differential_evolution step 845: f(x)= 0.4671860209465061
# differential_evolution step 846: f(x)= 0.4671860209465061
# differential_evolution step 847: f(x)= 0.4671860209465061
# differential_evolution step 848: f(x)= 0.4671860209465061
# differential_evolution step 849: f(x)= 0.4671860209465061
# differential_evolution step 850: f(x)= 0.46718139731322933
# differential_evolution step 851: f(x)= 0.46718139731322933
# differential_evolution step 852: f(x)= 0.46718139731322933
# differential_evolution step 853: f(x)= 0.46718139731322933
# differential_evolution step 854: f(x)= 0.46718139731322933
# differential_evolution step 855: f(x)= 0.46718139731322933
# differential_evolution step 856: f(x)= 0.46718139731322933
# differential_evolution step 857: f(x)= 0.46718139731322933
# differential_evolution step 858: f(x)= 0.46718139731322933
# differential_evolution step 859: f(x)= 0.46718139731322933
# differential_evolution step 860: f(x)= 0.46718139731322933
# differential_evolution step 861: f(x)= 0.4671807873211595
# differential_evolution step 862: f(x)= 0.4671807873211595
# differential_evolution step 863: f(x)= 0.4671807873211595
# differential_evolution step 864: f(x)= 0.4671807873211595
# differential_evolution step 865: f(x)= 0.4671807873211595
# differential_evolution step 866: f(x)= 0.4671807873211595
# differential_evolution step 867: f(x)= 0.4671807873211595
# differential_evolution step 868: f(x)= 0.4671807873211595
# differential_evolution step 869: f(x)= 0.46717526491603334
# differential_evolution step 870: f(x)= 0.4671750062463085
# differential_evolution step 871: f(x)= 0.467169724653254
# differential_evolution step 872: f(x)= 0.467169724653254
# differential_evolution step 873: f(x)= 0.467169724653254
# differential_evolution step 874: f(x)= 0.467169724653254
# differential_evolution step 875: f(x)= 0.467169724653254
# differential_evolution step 876: f(x)= 0.467169724653254
# differential_evolution step 877: f(x)= 0.467169724653254
# differential_evolution step 878: f(x)= 0.467169724653254
# differential_evolution step 879: f(x)= 0.467169724653254
# differential_evolution step 880: f(x)= 0.467169724653254
# differential_evolution step 881: f(x)= 0.467169724653254
# differential_evolution step 882: f(x)= 0.46716776357896805
# differential_evolution step 883: f(x)= 0.46716776357896805
# differential_evolution step 884: f(x)= 0.46716776357896805
# differential_evolution step 885: f(x)= 0.46716776357896805
# differential_evolution step 886: f(x)= 0.46716612334643043
# differential_evolution step 887: f(x)= 0.46716612334643043
# differential_evolution step 888: f(x)= 0.46716612334643043
# differential_evolution step 889: f(x)= 0.4671480397537512
# differential_evolution step 890: f(x)= 0.4671480397537512
# differential_evolution step 891: f(x)= 0.4671480397537512
# differential_evolution step 892: f(x)= 0.4671480397537512
# differential_evolution step 893: f(x)= 0.4671480397537512
# differential_evolution step 894: f(x)= 0.4671480397537512
# differential_evolution step 895: f(x)= 0.4671480397537512
# differential_evolution step 896: f(x)= 0.4671475134214842
# differential_evolution step 897: f(x)= 0.4671475134214842
# differential_evolution step 898: f(x)= 0.46714399126627143
# differential_evolution step 899: f(x)= 0.46714399126627143
# differential_evolution step 900: f(x)= 0.46714399126627143
# differential_evolution step 901: f(x)= 0.46714399126627143
# differential_evolution step 902: f(x)= 0.46714399126627143
# differential_evolution step 903: f(x)= 0.46714399126627143
# differential_evolution step 904: f(x)= 0.46714399126627143
# differential_evolution step 905: f(x)= 0.46714399126627143
# differential_evolution step 906: f(x)= 0.46714399126627143
# differential_evolution step 907: f(x)= 0.46714399126627143
# differential_evolution step 908: f(x)= 0.46714399126627143
# differential_evolution step 909: f(x)= 0.46714399126627143
# differential_evolution step 910: f(x)= 0.46714399126627143
# differential_evolution step 911: f(x)= 0.46714399126627143
# differential_evolution step 912: f(x)= 0.46714399126627143
# differential_evolution step 913: f(x)= 0.46714399126627143
# differential_evolution step 914: f(x)= 0.46714399126627143
# differential_evolution step 915: f(x)= 0.46714399126627143
# differential_evolution step 916: f(x)= 0.46714399126627143
# differential_evolution step 917: f(x)= 0.46714399126627143
# differential_evolution step 918: f(x)= 0.46714399126627143
# differential_evolution step 919: f(x)= 0.46714399126627143
# differential_evolution step 920: f(x)= 0.46714399126627143
# differential_evolution step 921: f(x)= 0.46714399126627143
# differential_evolution step 922: f(x)= 0.46714399126627143
# differential_evolution step 923: f(x)= 0.46714399126627143
# differential_evolution step 924: f(x)= 0.46714300318722285
# differential_evolution step 925: f(x)= 0.46714300318722285
# differential_evolution step 926: f(x)= 0.46713832221766893
# differential_evolution step 927: f(x)= 0.4671278276066659
# differential_evolution step 928: f(x)= 0.4671278276066659
# differential_evolution step 929: f(x)= 0.4671278276066659
# differential_evolution step 930: f(x)= 0.46711670686092294
# differential_evolution step 931: f(x)= 0.46711594133837087
# differential_evolution step 932: f(x)= 0.46711594133837087
# differential_evolution step 933: f(x)= 0.46711594133837087
# differential_evolution step 934: f(x)= 0.46711594133837087
# differential_evolution step 935: f(x)= 0.46711594133837087
# differential_evolution step 936: f(x)= 0.46711594133837087
# differential_evolution step 937: f(x)= 0.46711594133837087
# differential_evolution step 938: f(x)= 0.46711594133837087
# differential_evolution step 939: f(x)= 0.46711594133837087
# differential_evolution step 940: f(x)= 0.4671146005419978
# differential_evolution step 941: f(x)= 0.46711209043838775
# differential_evolution step 942: f(x)= 0.46710441705583344
# differential_evolution step 943: f(x)= 0.46710441705583344
# differential_evolution step 944: f(x)= 0.46710441705583344
# differential_evolution step 945: f(x)= 0.46710441705583344
# differential_evolution step 946: f(x)= 0.46710441705583344
# differential_evolution step 947: f(x)= 0.46710059940121196
# differential_evolution step 948: f(x)= 0.46710059940121196
# differential_evolution step 949: f(x)= 0.46709679816002686
# differential_evolution step 950: f(x)= 0.46709679816002686
# differential_evolution step 951: f(x)= 0.46709526568155707
# differential_evolution step 952: f(x)= 0.46709526568155707
# differential_evolution step 953: f(x)= 0.46708439347699304
# differential_evolution step 954: f(x)= 0.46708439347699304
# differential_evolution step 955: f(x)= 0.46708439347699304
# differential_evolution step 956: f(x)= 0.46708439347699304
# differential_evolution step 957: f(x)= 0.46708439347699304
# differential_evolution step 958: f(x)= 0.46708439347699304
# differential_evolution step 959: f(x)= 0.46708439347699304
# differential_evolution step 960: f(x)= 0.46708439347699304
# differential_evolution step 961: f(x)= 0.4670793752970119
# differential_evolution step 962: f(x)= 0.4670793752970119
# differential_evolution step 963: f(x)= 0.4670793752970119
# differential_evolution step 964: f(x)= 0.4670793752970119
# differential_evolution step 965: f(x)= 0.4670722679933389
# differential_evolution step 966: f(x)= 0.4670722679933389
# differential_evolution step 967: f(x)= 0.4670722679933389
# differential_evolution step 968: f(x)= 0.4670722679933389
# differential_evolution step 969: f(x)= 0.4670682350884197
# differential_evolution step 970: f(x)= 0.4670682350884197
# differential_evolution step 971: f(x)= 0.4670682350884197
# differential_evolution step 972: f(x)= 0.4670682350884197
# differential_evolution step 973: f(x)= 0.4670682350884197
# differential_evolution step 974: f(x)= 0.4670682350884197
# differential_evolution step 975: f(x)= 0.4670682350884197
# differential_evolution step 976: f(x)= 0.4670682350884197
# differential_evolution step 977: f(x)= 0.4670682350884197
# differential_evolution step 978: f(x)= 0.46706596327844496
# differential_evolution step 979: f(x)= 0.4670619611981602
# differential_evolution step 980: f(x)= 0.4670619611981602
# differential_evolution step 981: f(x)= 0.4670619611981602
# differential_evolution step 982: f(x)= 0.4670619611981602
# differential_evolution step 983: f(x)= 0.4670619611981602
# differential_evolution step 984: f(x)= 0.4670598608101656
# differential_evolution step 985: f(x)= 0.4670560133857942
# differential_evolution step 986: f(x)= 0.4670560133857942
# differential_evolution step 987: f(x)= 0.4670560133857942
# differential_evolution step 988: f(x)= 0.4670560133857942
# differential_evolution step 989: f(x)= 0.46705105777086103
# differential_evolution step 990: f(x)= 0.46705105777086103
# differential_evolution step 991: f(x)= 0.46705105777086103
# differential_evolution step 992: f(x)= 0.4670495580399237
# differential_evolution step 993: f(x)= 0.4670453398299595
# differential_evolution step 994: f(x)= 0.4670453398299595
# differential_evolution step 995: f(x)= 0.4670453398299595
# differential_evolution step 996: f(x)= 0.4670453398299595
# differential_evolution step 997: f(x)= 0.4670453398299595
# differential_evolution step 998: f(x)= 0.4670453398299595
# differential_evolution step 999: f(x)= 0.4670453398299595
# differential_evolution step 1000: f(x)= 0.4670453398299595
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.0941035  49.99993954  1.71424432 56.24606151  0.37808462  3.17575378
#   0.70166098 86.44049026  0.18043637  3.77720299  0.31115813 14.50583028
#   0.16609932  0.87012727  1.49894292 35.77618289]
# Chi quadro minimo: 0.4670370941619719

# %%
# Plots:
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0671, r_e=64.8528, n=1.9348, x_0=56.2213
# Sérsic 2: I_e=0.3973, r_e=3.0853, n=0.6528, x_0=86.5404
# Sérsic 3: I_e=0.1868, r_e=3.5915, n=0.2554, x_0=14.5006
# Sérsic 4: I_e=0.2084, r_e=0.8785, n=1.1402, x_0=35.7430
# [ 0.03013478 22.68235997  0.33897439  0.04807786  0.12017487  0.47418785
#   0.23597422  0.16806761  0.06317869  0.52354853  0.2830778   0.46997077
#   2.03701849  2.47671394 10.85312565  0.28417719]
# 18.38169119304799
# 56.93590806051786 18.38169119304799 92.06441416885745 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (33, 38), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (64, 66)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 248240.9777841183
# differential_evolution step 2: f(x)= 57218.56414041811
# differential_evolution step 3: f(x)= 57218.56414041811
# differential_evolution step 4: f(x)= 28010.175092972553
# differential_evolution step 5: f(x)= 16755.638286278125
# differential_evolution step 6: f(x)= 6198.495539230433
# differential_evolution step 7: f(x)= 6198.495539230433
# differential_evolution step 8: f(x)= 6198.495539230433
# differential_evolution step 9: f(x)= 6198.495539230433
# differential_evolution step 10: f(x)= 6198.495539230433
# differential_evolution step 11: f(x)= 6198.495539230433
# differential_evolution step 12: f(x)= 6198.495539230433
# differential_evolution step 13: f(x)= 2815.2099647828627
# differential_evolution step 14: f(x)= 702.9238117708733
# differential_evolution step 15: f(x)= 702.9238117708733
# differential_evolution step 16: f(x)= 702.9238117708733
# differential_evolution step 17: f(x)= 702.9238117708733
# differential_evolution step 18: f(x)= 228.92076415615645
# differential_evolution step 19: f(x)= 228.92076415615645
# differential_evolution step 20: f(x)= 228.92076415615645
# differential_evolution step 21: f(x)= 228.92076415615645
# differential_evolution step 22: f(x)= 228.92076415615645
# differential_evolution step 23: f(x)= 205.900234211563
# differential_evolution step 24: f(x)= 205.900234211563
# differential_evolution step 25: f(x)= 156.00316674022395
# differential_evolution step 26: f(x)= 156.00316674022395
# differential_evolution step 27: f(x)= 156.00316674022395
# differential_evolution step 28: f(x)= 156.00316674022395
# differential_evolution step 29: f(x)= 156.00316674022395
# differential_evolution step 30: f(x)= 156.00316674022395
# differential_evolution step 31: f(x)= 156.00316674022395
# differential_evolution step 32: f(x)= 156.00316674022395
# differential_evolution step 33: f(x)= 156.00316674022395
# differential_evolution step 34: f(x)= 156.00316674022395
# differential_evolution step 35: f(x)= 156.00316674022395
# differential_evolution step 36: f(x)= 20.043597738118248
# differential_evolution step 37: f(x)= 20.043597738118248
# differential_evolution step 38: f(x)= 20.043597738118248
# differential_evolution step 39: f(x)= 20.043597738118248
# differential_evolution step 40: f(x)= 20.043597738118248
# differential_evolution step 41: f(x)= 20.043597738118248
# differential_evolution step 42: f(x)= 20.043597738118248
# differential_evolution step 43: f(x)= 20.043597738118248
# differential_evolution step 44: f(x)= 20.043597738118248
# differential_evolution step 45: f(x)= 20.043597738118248
# differential_evolution step 46: f(x)= 20.043597738118248
# differential_evolution step 47: f(x)= 5.93632062814873
# differential_evolution step 48: f(x)= 5.93632062814873
# differential_evolution step 49: f(x)= 5.93632062814873
# differential_evolution step 50: f(x)= 5.93632062814873
# differential_evolution step 51: f(x)= 5.93632062814873
# differential_evolution step 52: f(x)= 5.93632062814873
# differential_evolution step 53: f(x)= 5.93632062814873
# differential_evolution step 54: f(x)= 5.93632062814873
# differential_evolution step 55: f(x)= 5.93632062814873
# differential_evolution step 56: f(x)= 5.93632062814873
# differential_evolution step 57: f(x)= 5.93632062814873
# differential_evolution step 58: f(x)= 5.93632062814873
# differential_evolution step 59: f(x)= 5.93632062814873
# differential_evolution step 60: f(x)= 3.7604771836399045
# differential_evolution step 61: f(x)= 3.7604771836399045
# differential_evolution step 62: f(x)= 3.7604771836399045
# differential_evolution step 63: f(x)= 3.7604771836399045
# differential_evolution step 64: f(x)= 3.7604771836399045
# differential_evolution step 65: f(x)= 3.7604771836399045
# differential_evolution step 66: f(x)= 3.7604771836399045
# differential_evolution step 67: f(x)= 3.7604771836399045
# differential_evolution step 68: f(x)= 3.7604771836399045
# differential_evolution step 69: f(x)= 3.7604771836399045
# differential_evolution step 70: f(x)= 3.7604771836399045
# differential_evolution step 71: f(x)= 3.7604771836399045
# differential_evolution step 72: f(x)= 3.7604771836399045
# differential_evolution step 73: f(x)= 3.7604771836399045
# differential_evolution step 74: f(x)= 3.7604771836399045
# differential_evolution step 75: f(x)= 3.7604771836399045
# differential_evolution step 76: f(x)= 3.7604771836399045
# differential_evolution step 77: f(x)= 3.7604771836399045
# differential_evolution step 78: f(x)= 3.7604771836399045
# differential_evolution step 79: f(x)= 3.7604771836399045
# differential_evolution step 80: f(x)= 3.7604771836399045
# differential_evolution step 81: f(x)= 3.7604771836399045
# differential_evolution step 82: f(x)= 3.7604771836399045
# differential_evolution step 83: f(x)= 3.7604771836399045
# differential_evolution step 84: f(x)= 3.7604771836399045
# differential_evolution step 85: f(x)= 3.7604771836399045
# differential_evolution step 86: f(x)= 3.7604771836399045
# differential_evolution step 87: f(x)= 3.7604771836399045
# differential_evolution step 88: f(x)= 3.7604771836399045
# differential_evolution step 89: f(x)= 3.7604771836399045
# differential_evolution step 90: f(x)= 3.7604771836399045
# differential_evolution step 91: f(x)= 3.7604771836399045
# differential_evolution step 92: f(x)= 3.7604771836399045
# differential_evolution step 93: f(x)= 3.7604771836399045
# differential_evolution step 94: f(x)= 3.7604771836399045
# differential_evolution step 95: f(x)= 3.7604771836399045
# differential_evolution step 96: f(x)= 3.7604771836399045
# differential_evolution step 97: f(x)= 3.7604771836399045
# differential_evolution step 98: f(x)= 3.7604771836399045
# differential_evolution step 99: f(x)= 3.7604771836399045
# differential_evolution step 100: f(x)= 3.7604771836399045
# differential_evolution step 101: f(x)= 3.7604771836399045
# differential_evolution step 102: f(x)= 3.7604771836399045
# differential_evolution step 103: f(x)= 3.7604771836399045
# differential_evolution step 104: f(x)= 3.7604771836399045
# differential_evolution step 105: f(x)= 3.7604771836399045
# differential_evolution step 106: f(x)= 3.7604771836399045
# differential_evolution step 107: f(x)= 3.7604771836399045
# differential_evolution step 108: f(x)= 3.7604771836399045
# differential_evolution step 109: f(x)= 3.7604771836399045
# differential_evolution step 110: f(x)= 3.7604771836399045
# differential_evolution step 111: f(x)= 3.7604771836399045
# differential_evolution step 112: f(x)= 3.028796589173737
# differential_evolution step 113: f(x)= 3.028796589173737
# differential_evolution step 114: f(x)= 3.028796589173737
# differential_evolution step 115: f(x)= 3.028796589173737
# differential_evolution step 116: f(x)= 3.028796589173737
# differential_evolution step 117: f(x)= 1.712146061108356
# differential_evolution step 118: f(x)= 1.712146061108356
# differential_evolution step 119: f(x)= 1.712146061108356
# differential_evolution step 120: f(x)= 1.712146061108356
# differential_evolution step 121: f(x)= 1.712146061108356
# differential_evolution step 122: f(x)= 1.712146061108356
# differential_evolution step 123: f(x)= 1.712146061108356
# differential_evolution step 124: f(x)= 1.712146061108356
# differential_evolution step 125: f(x)= 1.712146061108356
# differential_evolution step 126: f(x)= 1.712146061108356
# differential_evolution step 127: f(x)= 1.712146061108356
# differential_evolution step 128: f(x)= 1.712146061108356
# differential_evolution step 129: f(x)= 1.712146061108356
# differential_evolution step 130: f(x)= 1.712146061108356
# differential_evolution step 131: f(x)= 1.712146061108356
# differential_evolution step 132: f(x)= 1.4131771627965666
# differential_evolution step 133: f(x)= 1.4131771627965666
# differential_evolution step 134: f(x)= 1.4131771627965666
# differential_evolution step 135: f(x)= 1.4131771627965666
# differential_evolution step 136: f(x)= 1.4131771627965666
# differential_evolution step 137: f(x)= 1.4131771627965666
# differential_evolution step 138: f(x)= 1.4131771627965666
# differential_evolution step 139: f(x)= 1.4131771627965666
# differential_evolution step 140: f(x)= 1.4131771627965666
# differential_evolution step 141: f(x)= 1.4131771627965666
# differential_evolution step 142: f(x)= 1.4131771627965666
# differential_evolution step 143: f(x)= 1.4131771627965666
# differential_evolution step 144: f(x)= 1.3734564020443714
# differential_evolution step 145: f(x)= 1.3734564020443714
# differential_evolution step 146: f(x)= 1.3734564020443714
# differential_evolution step 147: f(x)= 1.3734564020443714
# differential_evolution step 148: f(x)= 1.3734564020443714
# differential_evolution step 149: f(x)= 1.3734564020443714
# differential_evolution step 150: f(x)= 1.1974800205747216
# differential_evolution step 151: f(x)= 1.1974800205747216
# differential_evolution step 152: f(x)= 1.1974800205747216
# differential_evolution step 153: f(x)= 1.1974800205747216
# differential_evolution step 154: f(x)= 1.1974800205747216
# differential_evolution step 155: f(x)= 1.1974800205747216
# differential_evolution step 156: f(x)= 1.1974800205747216
# differential_evolution step 157: f(x)= 1.121681845823515
# differential_evolution step 158: f(x)= 1.121681845823515
# differential_evolution step 159: f(x)= 1.121681845823515
# differential_evolution step 160: f(x)= 1.121681845823515
# differential_evolution step 161: f(x)= 1.121681845823515
# differential_evolution step 162: f(x)= 1.121681845823515
# differential_evolution step 163: f(x)= 0.9705367760138719
# differential_evolution step 164: f(x)= 0.9705367760138719
# differential_evolution step 165: f(x)= 0.9705367760138719
# differential_evolution step 166: f(x)= 0.9705367760138719
# differential_evolution step 167: f(x)= 0.9705367760138719
# differential_evolution step 168: f(x)= 0.9705367760138719
# differential_evolution step 169: f(x)= 0.8677834420542072
# differential_evolution step 170: f(x)= 0.8677834420542072
# differential_evolution step 171: f(x)= 0.8677834420542072
# differential_evolution step 172: f(x)= 0.8677834420542072
# differential_evolution step 173: f(x)= 0.8677834420542072
# differential_evolution step 174: f(x)= 0.8677834420542072
# differential_evolution step 175: f(x)= 0.8677834420542072
# differential_evolution step 176: f(x)= 0.8677834420542072
# differential_evolution step 177: f(x)= 0.8677834420542072
# differential_evolution step 178: f(x)= 0.8677834420542072
# differential_evolution step 179: f(x)= 0.8677834420542072
# differential_evolution step 180: f(x)= 0.8677834420542072
# differential_evolution step 181: f(x)= 0.8634727981662701
# differential_evolution step 182: f(x)= 0.8634727981662701
# differential_evolution step 183: f(x)= 0.8634727981662701
# differential_evolution step 184: f(x)= 0.8634727981662701
# differential_evolution step 185: f(x)= 0.8634727981662701
# differential_evolution step 186: f(x)= 0.8094764574879543
# differential_evolution step 187: f(x)= 0.7781592564169554
# differential_evolution step 188: f(x)= 0.7781592564169554
# differential_evolution step 189: f(x)= 0.7781592564169554
# differential_evolution step 190: f(x)= 0.7781592564169554
# differential_evolution step 191: f(x)= 0.7781592564169554
# differential_evolution step 192: f(x)= 0.7781592564169554
# differential_evolution step 193: f(x)= 0.6498013041596901
# differential_evolution step 194: f(x)= 0.6498013041596901
# differential_evolution step 195: f(x)= 0.6498013041596901
# differential_evolution step 196: f(x)= 0.6498013041596901
# differential_evolution step 197: f(x)= 0.6498013041596901
# differential_evolution step 198: f(x)= 0.6498013041596901
# differential_evolution step 199: f(x)= 0.6498013041596901
# differential_evolution step 200: f(x)= 0.6498013041596901
# differential_evolution step 201: f(x)= 0.6498013041596901
# differential_evolution step 202: f(x)= 0.6498013041596901
# differential_evolution step 203: f(x)= 0.6498013041596901
# differential_evolution step 204: f(x)= 0.6498013041596901
# differential_evolution step 205: f(x)= 0.6498013041596901
# differential_evolution step 206: f(x)= 0.6498013041596901
# differential_evolution step 207: f(x)= 0.6498013041596901
# differential_evolution step 208: f(x)= 0.5960980978947233
# differential_evolution step 209: f(x)= 0.5960980978947233
# differential_evolution step 210: f(x)= 0.5960980978947233
# differential_evolution step 211: f(x)= 0.5960980978947233
# differential_evolution step 212: f(x)= 0.5960980978947233
# differential_evolution step 213: f(x)= 0.5893698422282263
# differential_evolution step 214: f(x)= 0.5893698422282263
# differential_evolution step 215: f(x)= 0.5893698422282263
# differential_evolution step 216: f(x)= 0.5893698422282263
# differential_evolution step 217: f(x)= 0.5870943696833177
# differential_evolution step 218: f(x)= 0.5870943696833177
# differential_evolution step 219: f(x)= 0.5870943696833177
# differential_evolution step 220: f(x)= 0.5870943696833177
# differential_evolution step 221: f(x)= 0.5870943696833177
# differential_evolution step 222: f(x)= 0.5870943696833177
# differential_evolution step 223: f(x)= 0.5870943696833177
# differential_evolution step 224: f(x)= 0.5870943696833177
# differential_evolution step 225: f(x)= 0.5870943696833177
# differential_evolution step 226: f(x)= 0.5724510888301481
# differential_evolution step 227: f(x)= 0.5724510888301481
# differential_evolution step 228: f(x)= 0.5724510888301481
# differential_evolution step 229: f(x)= 0.5724510888301481
# differential_evolution step 230: f(x)= 0.5706689875898164
# differential_evolution step 231: f(x)= 0.5629761534441287
# differential_evolution step 232: f(x)= 0.5629761534441287
# differential_evolution step 233: f(x)= 0.5629761534441287
# differential_evolution step 234: f(x)= 0.5629761534441287
# differential_evolution step 235: f(x)= 0.5629761534441287
# differential_evolution step 236: f(x)= 0.5451349874463498
# differential_evolution step 237: f(x)= 0.5451349874463498
# differential_evolution step 238: f(x)= 0.5451349874463498
# differential_evolution step 239: f(x)= 0.5451349874463498
# differential_evolution step 240: f(x)= 0.5451349874463498
# differential_evolution step 241: f(x)= 0.5451349874463498
# differential_evolution step 242: f(x)= 0.5451349874463498
# differential_evolution step 243: f(x)= 0.5451349874463498
# differential_evolution step 244: f(x)= 0.5261448661550954
# differential_evolution step 245: f(x)= 0.5261448661550954
# differential_evolution step 246: f(x)= 0.5261448661550954
# differential_evolution step 247: f(x)= 0.5261448661550954
# differential_evolution step 248: f(x)= 0.5261448661550954
# differential_evolution step 249: f(x)= 0.5261448661550954
# differential_evolution step 250: f(x)= 0.5261448661550954
# differential_evolution step 251: f(x)= 0.5261448661550954
# differential_evolution step 252: f(x)= 0.5261448661550954
# differential_evolution step 253: f(x)= 0.5261448661550954
# differential_evolution step 254: f(x)= 0.5261448661550954
# differential_evolution step 255: f(x)= 0.5261448661550954
# differential_evolution step 256: f(x)= 0.5261448661550954
# differential_evolution step 257: f(x)= 0.5261448661550954
# differential_evolution step 258: f(x)= 0.5261448661550954
# differential_evolution step 259: f(x)= 0.5261448661550954
# differential_evolution step 260: f(x)= 0.5261448661550954
# differential_evolution step 261: f(x)= 0.5261448661550954
# differential_evolution step 262: f(x)= 0.5261448661550954
# differential_evolution step 263: f(x)= 0.5082287157170794
# differential_evolution step 264: f(x)= 0.5082287157170794
# differential_evolution step 265: f(x)= 0.5082287157170794
# differential_evolution step 266: f(x)= 0.5082287157170794
# differential_evolution step 267: f(x)= 0.4939973902520841
# differential_evolution step 268: f(x)= 0.4939973902520841
# differential_evolution step 269: f(x)= 0.4939973902520841
# differential_evolution step 270: f(x)= 0.4939973902520841
# differential_evolution step 271: f(x)= 0.4939973902520841
# differential_evolution step 272: f(x)= 0.4939973902520841
# differential_evolution step 273: f(x)= 0.4939973902520841
# differential_evolution step 274: f(x)= 0.4939973902520841
# differential_evolution step 275: f(x)= 0.49338145094741054
# differential_evolution step 276: f(x)= 0.49338145094741054
# differential_evolution step 277: f(x)= 0.49338145094741054
# differential_evolution step 278: f(x)= 0.49338145094741054
# differential_evolution step 279: f(x)= 0.49338145094741054
# differential_evolution step 280: f(x)= 0.49338145094741054
# differential_evolution step 281: f(x)= 0.49338145094741054
# differential_evolution step 282: f(x)= 0.49338145094741054
# differential_evolution step 283: f(x)= 0.49338145094741054
# differential_evolution step 284: f(x)= 0.49338145094741054
# differential_evolution step 285: f(x)= 0.49338145094741054
# differential_evolution step 286: f(x)= 0.49338145094741054
# differential_evolution step 287: f(x)= 0.4879140292816799
# differential_evolution step 288: f(x)= 0.4879140292816799
# differential_evolution step 289: f(x)= 0.4879140292816799
# differential_evolution step 290: f(x)= 0.4879140292816799
# differential_evolution step 291: f(x)= 0.4879140292816799
# differential_evolution step 292: f(x)= 0.4879140292816799
# differential_evolution step 293: f(x)= 0.4879140292816799
# differential_evolution step 294: f(x)= 0.4879140292816799
# differential_evolution step 295: f(x)= 0.4879140292816799
# differential_evolution step 296: f(x)= 0.4879140292816799
# differential_evolution step 297: f(x)= 0.4879140292816799
# differential_evolution step 298: f(x)= 0.4879140292816799
# differential_evolution step 299: f(x)= 0.4879140292816799
# differential_evolution step 300: f(x)= 0.4879140292816799
# differential_evolution step 301: f(x)= 0.4879140292816799
# differential_evolution step 302: f(x)= 0.4879140292816799
# differential_evolution step 303: f(x)= 0.4879140292816799
# differential_evolution step 304: f(x)= 0.4879140292816799
# differential_evolution step 305: f(x)= 0.4879140292816799
# differential_evolution step 306: f(x)= 0.4879140292816799
# differential_evolution step 307: f(x)= 0.48308808730141256
# differential_evolution step 308: f(x)= 0.48308808730141256
# differential_evolution step 309: f(x)= 0.48308808730141256
# differential_evolution step 310: f(x)= 0.48308808730141256
# differential_evolution step 311: f(x)= 0.48308808730141256
# differential_evolution step 312: f(x)= 0.47788933438991926
# differential_evolution step 313: f(x)= 0.47788933438991926
# differential_evolution step 314: f(x)= 0.47788933438991926
# differential_evolution step 315: f(x)= 0.47788933438991926
# differential_evolution step 316: f(x)= 0.47788933438991926
# differential_evolution step 317: f(x)= 0.47788933438991926
# differential_evolution step 318: f(x)= 0.47788933438991926
# differential_evolution step 319: f(x)= 0.47788933438991926
# differential_evolution step 320: f(x)= 0.47788933438991926
# differential_evolution step 321: f(x)= 0.47788933438991926
# differential_evolution step 322: f(x)= 0.47788933438991926
# differential_evolution step 323: f(x)= 0.47788933438991926
# differential_evolution step 324: f(x)= 0.47788933438991926
# differential_evolution step 325: f(x)= 0.47788933438991926
# differential_evolution step 326: f(x)= 0.45966647217640133
# differential_evolution step 327: f(x)= 0.45966647217640133
# differential_evolution step 328: f(x)= 0.45966647217640133
# differential_evolution step 329: f(x)= 0.45966647217640133
# differential_evolution step 330: f(x)= 0.45966647217640133
# differential_evolution step 331: f(x)= 0.45966647217640133
# differential_evolution step 332: f(x)= 0.45966647217640133
# differential_evolution step 333: f(x)= 0.45966647217640133
# differential_evolution step 334: f(x)= 0.45966647217640133
# differential_evolution step 335: f(x)= 0.45966647217640133
# differential_evolution step 336: f(x)= 0.45966647217640133
# differential_evolution step 337: f(x)= 0.45966647217640133
# differential_evolution step 338: f(x)= 0.45966647217640133
# differential_evolution step 339: f(x)= 0.45966647217640133
# differential_evolution step 340: f(x)= 0.45966647217640133
# differential_evolution step 341: f(x)= 0.45966647217640133
# differential_evolution step 342: f(x)= 0.45966647217640133
# differential_evolution step 343: f(x)= 0.45966647217640133
# differential_evolution step 344: f(x)= 0.45966647217640133
# differential_evolution step 345: f(x)= 0.45966647217640133
# differential_evolution step 346: f(x)= 0.45966647217640133
# differential_evolution step 347: f(x)= 0.42873494998336553
# differential_evolution step 348: f(x)= 0.42873494998336553
# differential_evolution step 349: f(x)= 0.42873494998336553
# differential_evolution step 350: f(x)= 0.42873494998336553
# differential_evolution step 351: f(x)= 0.42873494998336553
# differential_evolution step 352: f(x)= 0.42873494998336553
# differential_evolution step 353: f(x)= 0.42873494998336553
# differential_evolution step 354: f(x)= 0.42873494998336553
# differential_evolution step 355: f(x)= 0.42873494998336553
# differential_evolution step 356: f(x)= 0.42873494998336553
# differential_evolution step 357: f(x)= 0.42873494998336553
# differential_evolution step 358: f(x)= 0.42873494998336553
# differential_evolution step 359: f(x)= 0.42873494998336553
# differential_evolution step 360: f(x)= 0.42873494998336553
# differential_evolution step 361: f(x)= 0.42873494998336553
# differential_evolution step 362: f(x)= 0.42873494998336553
# differential_evolution step 363: f(x)= 0.42873494998336553
# differential_evolution step 364: f(x)= 0.42873494998336553
# differential_evolution step 365: f(x)= 0.42873494998336553
# differential_evolution step 366: f(x)= 0.42873494998336553
# differential_evolution step 367: f(x)= 0.42873494998336553
# differential_evolution step 368: f(x)= 0.42873494998336553
# differential_evolution step 369: f(x)= 0.42873494998336553
# differential_evolution step 370: f(x)= 0.42873494998336553
# differential_evolution step 371: f(x)= 0.42873494998336553
# differential_evolution step 372: f(x)= 0.42873494998336553
# differential_evolution step 373: f(x)= 0.42873494998336553
# differential_evolution step 374: f(x)= 0.42873494998336553
# differential_evolution step 375: f(x)= 0.42873494998336553
# differential_evolution step 376: f(x)= 0.42873494998336553
# differential_evolution step 377: f(x)= 0.42873494998336553
# differential_evolution step 378: f(x)= 0.4166900084155839
# differential_evolution step 379: f(x)= 0.4166900084155839
# differential_evolution step 380: f(x)= 0.4166900084155839
# differential_evolution step 381: f(x)= 0.4166900084155839
# differential_evolution step 382: f(x)= 0.4166900084155839
# differential_evolution step 383: f(x)= 0.4166900084155839
# differential_evolution step 384: f(x)= 0.4166900084155839
# differential_evolution step 385: f(x)= 0.4166900084155839
# differential_evolution step 386: f(x)= 0.4166900084155839
# differential_evolution step 387: f(x)= 0.4166900084155839
# differential_evolution step 388: f(x)= 0.4166900084155839
# differential_evolution step 389: f(x)= 0.4166900084155839
# differential_evolution step 390: f(x)= 0.4166900084155839
# differential_evolution step 391: f(x)= 0.3999158810966206
# differential_evolution step 392: f(x)= 0.3999158810966206
# differential_evolution step 393: f(x)= 0.3999158810966206
# differential_evolution step 394: f(x)= 0.3999158810966206
# differential_evolution step 395: f(x)= 0.3999158810966206
# differential_evolution step 396: f(x)= 0.3999158810966206
# differential_evolution step 397: f(x)= 0.3999158810966206
# differential_evolution step 398: f(x)= 0.3999158810966206
# differential_evolution step 399: f(x)= 0.3999158810966206
# differential_evolution step 400: f(x)= 0.3999158810966206
# differential_evolution step 401: f(x)= 0.39864413363902645
# differential_evolution step 402: f(x)= 0.39864413363902645
# differential_evolution step 403: f(x)= 0.39864413363902645
# differential_evolution step 404: f(x)= 0.39864413363902645
# differential_evolution step 405: f(x)= 0.39864413363902645
# differential_evolution step 406: f(x)= 0.39864413363902645
# differential_evolution step 407: f(x)= 0.39864413363902645
# differential_evolution step 408: f(x)= 0.39864413363902645
# differential_evolution step 409: f(x)= 0.39864413363902645
# differential_evolution step 410: f(x)= 0.39864413363902645
# differential_evolution step 411: f(x)= 0.39864413363902645
# differential_evolution step 412: f(x)= 0.39864413363902645
# differential_evolution step 413: f(x)= 0.39864413363902645
# differential_evolution step 414: f(x)= 0.39864413363902645
# differential_evolution step 415: f(x)= 0.39864413363902645
# differential_evolution step 416: f(x)= 0.39864413363902645
# differential_evolution step 417: f(x)= 0.39864413363902645
# differential_evolution step 418: f(x)= 0.39864413363902645
# differential_evolution step 419: f(x)= 0.39864413363902645
# differential_evolution step 420: f(x)= 0.3887103858665608
# differential_evolution step 421: f(x)= 0.3887103858665608
# differential_evolution step 422: f(x)= 0.3887103858665608
# differential_evolution step 423: f(x)= 0.3887103858665608
# differential_evolution step 424: f(x)= 0.3887103858665608
# differential_evolution step 425: f(x)= 0.3887103858665608
# differential_evolution step 426: f(x)= 0.3887103858665608
# differential_evolution step 427: f(x)= 0.3887103858665608
# differential_evolution step 428: f(x)= 0.3887103858665608
# differential_evolution step 429: f(x)= 0.3887103858665608
# differential_evolution step 430: f(x)= 0.3887103858665608
# differential_evolution step 431: f(x)= 0.3887103858665608
# differential_evolution step 432: f(x)= 0.3887103858665608
# differential_evolution step 433: f(x)= 0.3887103858665608
# differential_evolution step 434: f(x)= 0.3887103858665608
# differential_evolution step 435: f(x)= 0.3887103858665608
# differential_evolution step 436: f(x)= 0.3815437595357955
# differential_evolution step 437: f(x)= 0.3815437595357955
# differential_evolution step 438: f(x)= 0.3815437595357955
# differential_evolution step 439: f(x)= 0.3815437595357955
# differential_evolution step 440: f(x)= 0.3815437595357955
# differential_evolution step 441: f(x)= 0.3815437595357955
# differential_evolution step 442: f(x)= 0.3815437595357955
# differential_evolution step 443: f(x)= 0.3815437595357955
# differential_evolution step 444: f(x)= 0.3815437595357955
# differential_evolution step 445: f(x)= 0.3815437595357955
# differential_evolution step 446: f(x)= 0.3815437595357955
# differential_evolution step 447: f(x)= 0.3815437595357955
# differential_evolution step 448: f(x)= 0.3815437595357955
# differential_evolution step 449: f(x)= 0.3815437595357955
# differential_evolution step 450: f(x)= 0.3815437595357955
# differential_evolution step 451: f(x)= 0.3815437595357955
# differential_evolution step 452: f(x)= 0.3815437595357955
# differential_evolution step 453: f(x)= 0.3815437595357955
# differential_evolution step 454: f(x)= 0.3815437595357955
# differential_evolution step 455: f(x)= 0.3815437595357955
# differential_evolution step 456: f(x)= 0.3815437595357955
# differential_evolution step 457: f(x)= 0.3815437595357955
# differential_evolution step 458: f(x)= 0.3815437595357955
# differential_evolution step 459: f(x)= 0.3815437595357955
# differential_evolution step 460: f(x)= 0.3815437595357955
# differential_evolution step 461: f(x)= 0.3815437595357955
# differential_evolution step 462: f(x)= 0.37705184438297434
# differential_evolution step 463: f(x)= 0.37705184438297434
# differential_evolution step 464: f(x)= 0.37705184438297434
# differential_evolution step 465: f(x)= 0.371108650753628
# differential_evolution step 466: f(x)= 0.371108650753628
# differential_evolution step 467: f(x)= 0.371108650753628
# differential_evolution step 468: f(x)= 0.371108650753628
# differential_evolution step 469: f(x)= 0.371108650753628
# differential_evolution step 470: f(x)= 0.371108650753628
# differential_evolution step 471: f(x)= 0.371108650753628
# differential_evolution step 472: f(x)= 0.371108650753628
# differential_evolution step 473: f(x)= 0.371108650753628
# differential_evolution step 474: f(x)= 0.371108650753628
# differential_evolution step 475: f(x)= 0.3656344731247101
# differential_evolution step 476: f(x)= 0.3656344731247101
# differential_evolution step 477: f(x)= 0.3656344731247101
# differential_evolution step 478: f(x)= 0.3656344731247101
# differential_evolution step 479: f(x)= 0.3656344731247101
# differential_evolution step 480: f(x)= 0.3656344731247101
# differential_evolution step 481: f(x)= 0.3656344731247101
# differential_evolution step 482: f(x)= 0.3656344731247101
# differential_evolution step 483: f(x)= 0.3656344731247101
# differential_evolution step 484: f(x)= 0.3656344731247101
# differential_evolution step 485: f(x)= 0.3656344731247101
# differential_evolution step 486: f(x)= 0.3656344731247101
# differential_evolution step 487: f(x)= 0.3656344731247101
# differential_evolution step 488: f(x)= 0.3656344731247101
# differential_evolution step 489: f(x)= 0.3656344731247101
# differential_evolution step 490: f(x)= 0.3656344731247101
# differential_evolution step 491: f(x)= 0.3656344731247101
# differential_evolution step 492: f(x)= 0.3656344731247101
# differential_evolution step 493: f(x)= 0.3656344731247101
# differential_evolution step 494: f(x)= 0.36422991592362114
# differential_evolution step 495: f(x)= 0.36422991592362114
# differential_evolution step 496: f(x)= 0.36422991592362114
# differential_evolution step 497: f(x)= 0.36422991592362114
# differential_evolution step 498: f(x)= 0.36422991592362114
# differential_evolution step 499: f(x)= 0.36422991592362114
# differential_evolution step 500: f(x)= 0.3616876235159499
# differential_evolution step 501: f(x)= 0.3616876235159499
# differential_evolution step 502: f(x)= 0.3616876235159499
# differential_evolution step 503: f(x)= 0.3616876235159499
# differential_evolution step 504: f(x)= 0.3612577104093072
# differential_evolution step 505: f(x)= 0.3607180166849625
# differential_evolution step 506: f(x)= 0.35343018462276177
# differential_evolution step 507: f(x)= 0.35343018462276177
# differential_evolution step 508: f(x)= 0.3498253463474827
# differential_evolution step 509: f(x)= 0.3498253463474827
# differential_evolution step 510: f(x)= 0.3498253463474827
# differential_evolution step 511: f(x)= 0.3498253463474827
# differential_evolution step 512: f(x)= 0.3498253463474827
# differential_evolution step 513: f(x)= 0.3498253463474827
# differential_evolution step 514: f(x)= 0.3498253463474827
# differential_evolution step 515: f(x)= 0.3498253463474827
# differential_evolution step 516: f(x)= 0.34937672763071365
# differential_evolution step 517: f(x)= 0.34937672763071365
# differential_evolution step 518: f(x)= 0.34937672763071365
# differential_evolution step 519: f(x)= 0.34937672763071365
# differential_evolution step 520: f(x)= 0.34937672763071365
# differential_evolution step 521: f(x)= 0.34937672763071365
# differential_evolution step 522: f(x)= 0.34937672763071365
# differential_evolution step 523: f(x)= 0.34937672763071365
# differential_evolution step 524: f(x)= 0.34937672763071365
# differential_evolution step 525: f(x)= 0.34937672763071365
# differential_evolution step 526: f(x)= 0.34937672763071365
# differential_evolution step 527: f(x)= 0.34937672763071365
# differential_evolution step 528: f(x)= 0.34937672763071365
# differential_evolution step 529: f(x)= 0.34937672763071365
# differential_evolution step 530: f(x)= 0.34937672763071365
# differential_evolution step 531: f(x)= 0.34937672763071365
# differential_evolution step 532: f(x)= 0.34937672763071365
# differential_evolution step 533: f(x)= 0.34937672763071365
# differential_evolution step 534: f(x)= 0.34937672763071365
# differential_evolution step 535: f(x)= 0.34937672763071365
# differential_evolution step 536: f(x)= 0.34937672763071365
# differential_evolution step 537: f(x)= 0.34937672763071365
# differential_evolution step 538: f(x)= 0.34937672763071365
# differential_evolution step 539: f(x)= 0.34699953425219493
# differential_evolution step 540: f(x)= 0.34699953425219493
# differential_evolution step 541: f(x)= 0.34699953425219493
# differential_evolution step 542: f(x)= 0.34699953425219493
# differential_evolution step 543: f(x)= 0.34699953425219493
# differential_evolution step 544: f(x)= 0.34699953425219493
# differential_evolution step 545: f(x)= 0.34699953425219493
# differential_evolution step 546: f(x)= 0.34699953425219493
# differential_evolution step 547: f(x)= 0.34699953425219493
# differential_evolution step 548: f(x)= 0.34598525096631616
# differential_evolution step 549: f(x)= 0.34598525096631616
# differential_evolution step 550: f(x)= 0.34598525096631616
# differential_evolution step 551: f(x)= 0.34598525096631616
# differential_evolution step 552: f(x)= 0.34598525096631616
# differential_evolution step 553: f(x)= 0.3412597300301568
# differential_evolution step 554: f(x)= 0.3412597300301568
# differential_evolution step 555: f(x)= 0.3412597300301568
# differential_evolution step 556: f(x)= 0.3412597300301568
# differential_evolution step 557: f(x)= 0.3412597300301568
# differential_evolution step 558: f(x)= 0.3412597300301568
# differential_evolution step 559: f(x)= 0.3412597300301568
# differential_evolution step 560: f(x)= 0.3412597300301568
# differential_evolution step 561: f(x)= 0.3412597300301568
# differential_evolution step 562: f(x)= 0.3412597300301568
# differential_evolution step 563: f(x)= 0.3412597300301568
# differential_evolution step 564: f(x)= 0.3412597300301568
# differential_evolution step 565: f(x)= 0.3412597300301568
# differential_evolution step 566: f(x)= 0.3412597300301568
# differential_evolution step 567: f(x)= 0.3412597300301568
# differential_evolution step 568: f(x)= 0.3412597300301568
# differential_evolution step 569: f(x)= 0.3412597300301568
# differential_evolution step 570: f(x)= 0.3405802293858185
# differential_evolution step 571: f(x)= 0.3405802293858185
# differential_evolution step 572: f(x)= 0.3405802293858185
# differential_evolution step 573: f(x)= 0.3405802293858185
# differential_evolution step 574: f(x)= 0.3405802293858185
# differential_evolution step 575: f(x)= 0.3405802293858185
# differential_evolution step 576: f(x)= 0.3405802293858185
# differential_evolution step 577: f(x)= 0.3405802293858185
# differential_evolution step 578: f(x)= 0.3405802293858185
# differential_evolution step 579: f(x)= 0.3405802293858185
# differential_evolution step 580: f(x)= 0.3405802293858185
# differential_evolution step 581: f(x)= 0.3405802293858185
# differential_evolution step 582: f(x)= 0.3405802293858185
# differential_evolution step 583: f(x)= 0.3405802293858185
# differential_evolution step 584: f(x)= 0.3405802293858185
# differential_evolution step 585: f(x)= 0.3405802293858185
# differential_evolution step 586: f(x)= 0.3405802293858185
# differential_evolution step 587: f(x)= 0.3405802293858185
# differential_evolution step 588: f(x)= 0.3405802293858185
# differential_evolution step 589: f(x)= 0.3405802293858185
# differential_evolution step 590: f(x)= 0.3405802293858185
# differential_evolution step 591: f(x)= 0.3405802293858185
# differential_evolution step 592: f(x)= 0.3405802293858185
# differential_evolution step 593: f(x)= 0.3405802293858185
# differential_evolution step 594: f(x)= 0.3405802293858185
# differential_evolution step 595: f(x)= 0.3405802293858185
# differential_evolution step 596: f(x)= 0.3405802293858185
# differential_evolution step 597: f(x)= 0.3405802293858185
# differential_evolution step 598: f(x)= 0.3405802293858185
# differential_evolution step 599: f(x)= 0.3405802293858185
# differential_evolution step 600: f(x)= 0.3405802293858185
# differential_evolution step 601: f(x)= 0.3405802293858185
# differential_evolution step 602: f(x)= 0.3405802293858185
# differential_evolution step 603: f(x)= 0.3405802293858185
# differential_evolution step 604: f(x)= 0.3405802293858185
# differential_evolution step 605: f(x)= 0.3405802293858185
# differential_evolution step 606: f(x)= 0.3405802293858185
# differential_evolution step 607: f(x)= 0.3405802293858185
# differential_evolution step 608: f(x)= 0.3405802293858185
# differential_evolution step 609: f(x)= 0.3405802293858185
# differential_evolution step 610: f(x)= 0.3405802293858185
# differential_evolution step 611: f(x)= 0.3405802293858185
# differential_evolution step 612: f(x)= 0.3405802293858185
# differential_evolution step 613: f(x)= 0.3405802293858185
# differential_evolution step 614: f(x)= 0.3405802293858185
# differential_evolution step 615: f(x)= 0.3405802293858185
# differential_evolution step 616: f(x)= 0.3405802293858185
# differential_evolution step 617: f(x)= 0.33534204614525076
# differential_evolution step 618: f(x)= 0.33534204614525076
# differential_evolution step 619: f(x)= 0.33454590946920154
# differential_evolution step 620: f(x)= 0.33454590946920154
# differential_evolution step 621: f(x)= 0.33454590946920154
# differential_evolution step 622: f(x)= 0.33454590946920154
# differential_evolution step 623: f(x)= 0.33454590946920154
# differential_evolution step 624: f(x)= 0.33454590946920154
# differential_evolution step 625: f(x)= 0.33454590946920154
# differential_evolution step 626: f(x)= 0.33454590946920154
# differential_evolution step 627: f(x)= 0.33454590946920154
# differential_evolution step 628: f(x)= 0.3339319922976897
# differential_evolution step 629: f(x)= 0.3339319922976897
# differential_evolution step 630: f(x)= 0.3339319922976897
# differential_evolution step 631: f(x)= 0.3339319922976897
# differential_evolution step 632: f(x)= 0.3339319922976897
# differential_evolution step 633: f(x)= 0.3339319922976897
# differential_evolution step 634: f(x)= 0.3339319922976897
# differential_evolution step 635: f(x)= 0.3339319922976897
# differential_evolution step 636: f(x)= 0.3339319922976897
# differential_evolution step 637: f(x)= 0.3339319922976897
# differential_evolution step 638: f(x)= 0.3339319922976897
# differential_evolution step 639: f(x)= 0.3339319922976897
# differential_evolution step 640: f(x)= 0.3339319922976897
# differential_evolution step 641: f(x)= 0.3339319922976897
# differential_evolution step 642: f(x)= 0.3339319922976897
# differential_evolution step 643: f(x)= 0.3339319922976897
# differential_evolution step 644: f(x)= 0.3339319922976897
# differential_evolution step 645: f(x)= 0.33307123257791166
# differential_evolution step 646: f(x)= 0.33307123257791166
# differential_evolution step 647: f(x)= 0.33307123257791166
# differential_evolution step 648: f(x)= 0.33307123257791166
# differential_evolution step 649: f(x)= 0.33307123257791166
# differential_evolution step 650: f(x)= 0.33307123257791166
# differential_evolution step 651: f(x)= 0.33307123257791166
# differential_evolution step 652: f(x)= 0.33307123257791166
# differential_evolution step 653: f(x)= 0.33307123257791166
# differential_evolution step 654: f(x)= 0.33307123257791166
# differential_evolution step 655: f(x)= 0.33307123257791166
# differential_evolution step 656: f(x)= 0.33307123257791166
# differential_evolution step 657: f(x)= 0.33307123257791166
# differential_evolution step 658: f(x)= 0.33307123257791166
# differential_evolution step 659: f(x)= 0.33307123257791166
# differential_evolution step 660: f(x)= 0.33307123257791166
# differential_evolution step 661: f(x)= 0.33307123257791166
# differential_evolution step 662: f(x)= 0.33307123257791166
# differential_evolution step 663: f(x)= 0.3315122949967271
# differential_evolution step 664: f(x)= 0.3315122949967271
# differential_evolution step 665: f(x)= 0.3315122949967271
# differential_evolution step 666: f(x)= 0.3315122949967271
# differential_evolution step 667: f(x)= 0.32791546949352895
# differential_evolution step 668: f(x)= 0.32791546949352895
# differential_evolution step 669: f(x)= 0.32791546949352895
# differential_evolution step 670: f(x)= 0.32791546949352895
# differential_evolution step 671: f(x)= 0.32791546949352895
# differential_evolution step 672: f(x)= 0.3250962167236262
# differential_evolution step 673: f(x)= 0.3250962167236262
# differential_evolution step 674: f(x)= 0.3250962167236262
# differential_evolution step 675: f(x)= 0.3250962167236262
# differential_evolution step 676: f(x)= 0.3250962167236262
# differential_evolution step 677: f(x)= 0.3250962167236262
# differential_evolution step 678: f(x)= 0.3250962167236262
# differential_evolution step 679: f(x)= 0.3250962167236262
# differential_evolution step 680: f(x)= 0.3250962167236262
# differential_evolution step 681: f(x)= 0.3250962167236262
# differential_evolution step 682: f(x)= 0.3250962167236262
# differential_evolution step 683: f(x)= 0.3250962167236262
# differential_evolution step 684: f(x)= 0.3250962167236262
# differential_evolution step 685: f(x)= 0.3250962167236262
# differential_evolution step 686: f(x)= 0.3250962167236262
# differential_evolution step 687: f(x)= 0.3250962167236262
# differential_evolution step 688: f(x)= 0.3250962167236262
# differential_evolution step 689: f(x)= 0.3250962167236262
# differential_evolution step 690: f(x)= 0.3250962167236262
# differential_evolution step 691: f(x)= 0.3250962167236262
# differential_evolution step 692: f(x)= 0.3250962167236262
# differential_evolution step 693: f(x)= 0.3250962167236262
# differential_evolution step 694: f(x)= 0.3250962167236262
# differential_evolution step 695: f(x)= 0.3250962167236262
# differential_evolution step 696: f(x)= 0.3250962167236262
# differential_evolution step 697: f(x)= 0.3250962167236262
# differential_evolution step 698: f(x)= 0.3250962167236262
# differential_evolution step 699: f(x)= 0.3250962167236262
# differential_evolution step 700: f(x)= 0.3250962167236262
# differential_evolution step 701: f(x)= 0.3250962167236262
# differential_evolution step 702: f(x)= 0.3250962167236262
# differential_evolution step 703: f(x)= 0.3250962167236262
# differential_evolution step 704: f(x)= 0.3250962167236262
# differential_evolution step 705: f(x)= 0.3250962167236262
# differential_evolution step 706: f(x)= 0.324887525393595
# differential_evolution step 707: f(x)= 0.324887525393595
# differential_evolution step 708: f(x)= 0.324887525393595
# differential_evolution step 709: f(x)= 0.3207887802224968
# differential_evolution step 710: f(x)= 0.3207887802224968
# differential_evolution step 711: f(x)= 0.3207887802224968
# differential_evolution step 712: f(x)= 0.3207887802224968
# differential_evolution step 713: f(x)= 0.3207887802224968
# differential_evolution step 714: f(x)= 0.3207887802224968
# differential_evolution step 715: f(x)= 0.3207887802224968
# differential_evolution step 716: f(x)= 0.3207887802224968
# differential_evolution step 717: f(x)= 0.3207887802224968
# differential_evolution step 718: f(x)= 0.3207887802224968
# differential_evolution step 719: f(x)= 0.3207887802224968
# differential_evolution step 720: f(x)= 0.3207887802224968
# differential_evolution step 721: f(x)= 0.3207887802224968
# differential_evolution step 722: f(x)= 0.3207887802224968
# differential_evolution step 723: f(x)= 0.3207887802224968
# differential_evolution step 724: f(x)= 0.3207887802224968
# differential_evolution step 725: f(x)= 0.3207887802224968
# differential_evolution step 726: f(x)= 0.3207887802224968
# differential_evolution step 727: f(x)= 0.3207887802224968
# differential_evolution step 728: f(x)= 0.3207887802224968
# differential_evolution step 729: f(x)= 0.3207887802224968
# differential_evolution step 730: f(x)= 0.3207887802224968
# differential_evolution step 731: f(x)= 0.3207887802224968
# differential_evolution step 732: f(x)= 0.3207887802224968
# differential_evolution step 733: f(x)= 0.3207887802224968
# differential_evolution step 734: f(x)= 0.3207887802224968
# differential_evolution step 735: f(x)= 0.3207887802224968
# differential_evolution step 736: f(x)= 0.3207887802224968
# differential_evolution step 737: f(x)= 0.3207887802224968
# differential_evolution step 738: f(x)= 0.3207887802224968
# differential_evolution step 739: f(x)= 0.3207887802224968
# differential_evolution step 740: f(x)= 0.3207887802224968
# differential_evolution step 741: f(x)= 0.3207887802224968
# differential_evolution step 742: f(x)= 0.3207887802224968
# differential_evolution step 743: f(x)= 0.3207887802224968
# differential_evolution step 744: f(x)= 0.3207887802224968
# differential_evolution step 745: f(x)= 0.31784253273440666
# differential_evolution step 746: f(x)= 0.31784253273440666
# differential_evolution step 747: f(x)= 0.31784253273440666
# differential_evolution step 748: f(x)= 0.31784253273440666
# differential_evolution step 749: f(x)= 0.3169034065726948
# differential_evolution step 750: f(x)= 0.3169034065726948
# differential_evolution step 751: f(x)= 0.3169034065726948
# differential_evolution step 752: f(x)= 0.3169034065726948
# differential_evolution step 753: f(x)= 0.3169034065726948
# differential_evolution step 754: f(x)= 0.3169034065726948
# differential_evolution step 755: f(x)= 0.3169034065726948
# differential_evolution step 756: f(x)= 0.3169034065726948
# differential_evolution step 757: f(x)= 0.3169034065726948
# differential_evolution step 758: f(x)= 0.3169034065726948
# differential_evolution step 759: f(x)= 0.3169034065726948
# differential_evolution step 760: f(x)= 0.3169034065726948
# differential_evolution step 761: f(x)= 0.3169034065726948
# differential_evolution step 762: f(x)= 0.3169034065726948
# differential_evolution step 763: f(x)= 0.3169034065726948
# differential_evolution step 764: f(x)= 0.3169034065726948
# differential_evolution step 765: f(x)= 0.3169034065726948
# differential_evolution step 766: f(x)= 0.31646613527075007
# differential_evolution step 767: f(x)= 0.31646613527075007
# differential_evolution step 768: f(x)= 0.31646613527075007
# differential_evolution step 769: f(x)= 0.31646613527075007
# differential_evolution step 770: f(x)= 0.31646613527075007
# differential_evolution step 771: f(x)= 0.31646613527075007
# differential_evolution step 772: f(x)= 0.31608835500543125
# differential_evolution step 773: f(x)= 0.31608835500543125
# differential_evolution step 774: f(x)= 0.31608835500543125
# differential_evolution step 775: f(x)= 0.31608835500543125
# differential_evolution step 776: f(x)= 0.31608835500543125
# differential_evolution step 777: f(x)= 0.31608835500543125
# differential_evolution step 778: f(x)= 0.31608835500543125
# differential_evolution step 779: f(x)= 0.31608835500543125
# differential_evolution step 780: f(x)= 0.31608835500543125
# differential_evolution step 781: f(x)= 0.31608835500543125
# differential_evolution step 782: f(x)= 0.31608835500543125
# differential_evolution step 783: f(x)= 0.31608835500543125
# differential_evolution step 784: f(x)= 0.31608835500543125
# differential_evolution step 785: f(x)= 0.31608835500543125
# differential_evolution step 786: f(x)= 0.31608835500543125
# differential_evolution step 787: f(x)= 0.31608835500543125
# differential_evolution step 788: f(x)= 0.31608835500543125
# differential_evolution step 789: f(x)= 0.31608835500543125
# differential_evolution step 790: f(x)= 0.31608835500543125
# differential_evolution step 791: f(x)= 0.31608835500543125
# differential_evolution step 792: f(x)= 0.31608835500543125
# differential_evolution step 793: f(x)= 0.31608835500543125
# differential_evolution step 794: f(x)= 0.31608835500543125
# differential_evolution step 795: f(x)= 0.31608835500543125
# differential_evolution step 796: f(x)= 0.31608835500543125
# differential_evolution step 797: f(x)= 0.31608835500543125
# differential_evolution step 798: f(x)= 0.31608835500543125
# differential_evolution step 799: f(x)= 0.31608835500543125
# differential_evolution step 800: f(x)= 0.3146838790505036
# differential_evolution step 801: f(x)= 0.3146838790505036
# differential_evolution step 802: f(x)= 0.3146838790505036
# differential_evolution step 803: f(x)= 0.3146838790505036
# differential_evolution step 804: f(x)= 0.3146838790505036
# differential_evolution step 805: f(x)= 0.3146838790505036
# differential_evolution step 806: f(x)= 0.3146838790505036
# differential_evolution step 807: f(x)= 0.3146838790505036
# differential_evolution step 808: f(x)= 0.3146838790505036
# differential_evolution step 809: f(x)= 0.3146838790505036
# differential_evolution step 810: f(x)= 0.3146838790505036
# differential_evolution step 811: f(x)= 0.31437390432562445
# differential_evolution step 812: f(x)= 0.31437390432562445
# differential_evolution step 813: f(x)= 0.31437390432562445
# differential_evolution step 814: f(x)= 0.31437390432562445
# differential_evolution step 815: f(x)= 0.31355613039348806
# differential_evolution step 816: f(x)= 0.31355613039348806
# differential_evolution step 817: f(x)= 0.31355613039348806
# differential_evolution step 818: f(x)= 0.31355613039348806
# differential_evolution step 819: f(x)= 0.31355613039348806
# differential_evolution step 820: f(x)= 0.31355613039348806
# differential_evolution step 821: f(x)= 0.31355613039348806
# differential_evolution step 822: f(x)= 0.31355613039348806
# differential_evolution step 823: f(x)= 0.31355613039348806
# differential_evolution step 824: f(x)= 0.31355613039348806
# differential_evolution step 825: f(x)= 0.31355613039348806
# differential_evolution step 826: f(x)= 0.31355613039348806
# differential_evolution step 827: f(x)= 0.31355613039348806
# differential_evolution step 828: f(x)= 0.31355613039348806
# differential_evolution step 829: f(x)= 0.31355613039348806
# differential_evolution step 830: f(x)= 0.31355613039348806
# differential_evolution step 831: f(x)= 0.31355613039348806
# differential_evolution step 832: f(x)= 0.31355613039348806
# differential_evolution step 833: f(x)= 0.31355613039348806
# differential_evolution step 834: f(x)= 0.31355613039348806
# differential_evolution step 835: f(x)= 0.31355613039348806
# differential_evolution step 836: f(x)= 0.31355613039348806
# differential_evolution step 837: f(x)= 0.31355613039348806
# differential_evolution step 838: f(x)= 0.31355613039348806
# differential_evolution step 839: f(x)= 0.31355613039348806
# differential_evolution step 840: f(x)= 0.31203384280944396
# differential_evolution step 841: f(x)= 0.31203384280944396
# differential_evolution step 842: f(x)= 0.31203384280944396
# differential_evolution step 843: f(x)= 0.31203384280944396
# differential_evolution step 844: f(x)= 0.31203384280944396
# differential_evolution step 845: f(x)= 0.31203384280944396
# differential_evolution step 846: f(x)= 0.31203384280944396
# differential_evolution step 847: f(x)= 0.31203384280944396
# differential_evolution step 848: f(x)= 0.31203384280944396
# differential_evolution step 849: f(x)= 0.31203384280944396
# differential_evolution step 850: f(x)= 0.31203384280944396
# differential_evolution step 851: f(x)= 0.31203384280944396
# differential_evolution step 852: f(x)= 0.31203384280944396
# differential_evolution step 853: f(x)= 0.31203384280944396
# differential_evolution step 854: f(x)= 0.3111595680993404
# differential_evolution step 855: f(x)= 0.3111595680993404
# differential_evolution step 856: f(x)= 0.3111595680993404
# differential_evolution step 857: f(x)= 0.3111595680993404
# differential_evolution step 858: f(x)= 0.3094020119848938
# differential_evolution step 859: f(x)= 0.3094020119848938
# differential_evolution step 860: f(x)= 0.3094020119848938
# differential_evolution step 861: f(x)= 0.3094020119848938
# differential_evolution step 862: f(x)= 0.3094020119848938
# differential_evolution step 863: f(x)= 0.3094020119848938
# differential_evolution step 864: f(x)= 0.3094020119848938
# differential_evolution step 865: f(x)= 0.3094020119848938
# differential_evolution step 866: f(x)= 0.3094020119848938
# differential_evolution step 867: f(x)= 0.3094020119848938
# differential_evolution step 868: f(x)= 0.3094020119848938
# differential_evolution step 869: f(x)= 0.3094020119848938
# differential_evolution step 870: f(x)= 0.3094020119848938
# differential_evolution step 871: f(x)= 0.3094020119848938
# differential_evolution step 872: f(x)= 0.3094020119848938
# differential_evolution step 873: f(x)= 0.3082014353896916
# differential_evolution step 874: f(x)= 0.3082014353896916
# differential_evolution step 875: f(x)= 0.3082014353896916
# differential_evolution step 876: f(x)= 0.3082014353896916
# differential_evolution step 877: f(x)= 0.3082014353896916
# differential_evolution step 878: f(x)= 0.3082014353896916
# differential_evolution step 879: f(x)= 0.3082014353896916
# differential_evolution step 880: f(x)= 0.3072931967721637
# differential_evolution step 881: f(x)= 0.3072931967721637
# differential_evolution step 882: f(x)= 0.3072931967721637
# differential_evolution step 883: f(x)= 0.3072931967721637
# differential_evolution step 884: f(x)= 0.3072931967721637
# differential_evolution step 885: f(x)= 0.3072931967721637
# differential_evolution step 886: f(x)= 0.3072931967721637
# differential_evolution step 887: f(x)= 0.3072931967721637
# differential_evolution step 888: f(x)= 0.3072931967721637
# differential_evolution step 889: f(x)= 0.3072931967721637
# differential_evolution step 890: f(x)= 0.3072931967721637
# differential_evolution step 891: f(x)= 0.3072931967721637
# differential_evolution step 892: f(x)= 0.3072931967721637
# differential_evolution step 893: f(x)= 0.3072931967721637
# differential_evolution step 894: f(x)= 0.3072931967721637
# differential_evolution step 895: f(x)= 0.3072931967721637
# differential_evolution step 896: f(x)= 0.3072931967721637
# differential_evolution step 897: f(x)= 0.3072931967721637
# differential_evolution step 898: f(x)= 0.3072931967721637
# differential_evolution step 899: f(x)= 0.3072931967721637
# differential_evolution step 900: f(x)= 0.3072931967721637
# differential_evolution step 901: f(x)= 0.3072931967721637
# differential_evolution step 902: f(x)= 0.3072931967721637
# differential_evolution step 903: f(x)= 0.30639150793059694
# differential_evolution step 904: f(x)= 0.30639150793059694
# differential_evolution step 905: f(x)= 0.30639150793059694
# differential_evolution step 906: f(x)= 0.3046618560295764
# differential_evolution step 907: f(x)= 0.3046618560295764
# differential_evolution step 908: f(x)= 0.3046618560295764
# differential_evolution step 909: f(x)= 0.3046618560295764
# differential_evolution step 910: f(x)= 0.3046618560295764
# differential_evolution step 911: f(x)= 0.3046618560295764
# differential_evolution step 912: f(x)= 0.3046618560295764
# differential_evolution step 913: f(x)= 0.3046618560295764
# differential_evolution step 914: f(x)= 0.3046618560295764
# differential_evolution step 915: f(x)= 0.3046618560295764
# differential_evolution step 916: f(x)= 0.3046618560295764
# differential_evolution step 917: f(x)= 0.3046618560295764
# differential_evolution step 918: f(x)= 0.3046618560295764
# differential_evolution step 919: f(x)= 0.30352461728287605
# differential_evolution step 920: f(x)= 0.30352461728287605
# differential_evolution step 921: f(x)= 0.30352461728287605
# differential_evolution step 922: f(x)= 0.30352461728287605
# differential_evolution step 923: f(x)= 0.30352461728287605
# differential_evolution step 924: f(x)= 0.30352461728287605
# differential_evolution step 925: f(x)= 0.30352461728287605
# differential_evolution step 926: f(x)= 0.30352461728287605
# differential_evolution step 927: f(x)= 0.30352461728287605
# differential_evolution step 928: f(x)= 0.30352461728287605
# differential_evolution step 929: f(x)= 0.30352461728287605
# differential_evolution step 930: f(x)= 0.30352461728287605
# differential_evolution step 931: f(x)= 0.30352461728287605
# differential_evolution step 932: f(x)= 0.30266983072957904
# differential_evolution step 933: f(x)= 0.30266983072957904
# differential_evolution step 934: f(x)= 0.30266983072957904
# differential_evolution step 935: f(x)= 0.30266983072957904
# differential_evolution step 936: f(x)= 0.30266983072957904
# differential_evolution step 937: f(x)= 0.30266983072957904
# differential_evolution step 938: f(x)= 0.30266983072957904
# differential_evolution step 939: f(x)= 0.30266983072957904
# differential_evolution step 940: f(x)= 0.30266983072957904
# differential_evolution step 941: f(x)= 0.30266983072957904
# differential_evolution step 942: f(x)= 0.30266983072957904
# differential_evolution step 943: f(x)= 0.30266983072957904
# differential_evolution step 944: f(x)= 0.30266983072957904
# differential_evolution step 945: f(x)= 0.30266983072957904
# differential_evolution step 946: f(x)= 0.30266983072957904
# differential_evolution step 947: f(x)= 0.30266983072957904
# differential_evolution step 948: f(x)= 0.30266983072957904
# differential_evolution step 949: f(x)= 0.30266983072957904
# differential_evolution step 950: f(x)= 0.30266983072957904
# differential_evolution step 951: f(x)= 0.30266983072957904
# differential_evolution step 952: f(x)= 0.30266983072957904
# differential_evolution step 953: f(x)= 0.30266983072957904
# differential_evolution step 954: f(x)= 0.30266983072957904
# differential_evolution step 955: f(x)= 0.30266983072957904
# differential_evolution step 956: f(x)= 0.30266983072957904
# differential_evolution step 957: f(x)= 0.30266983072957904
# differential_evolution step 958: f(x)= 0.30266983072957904
# differential_evolution step 959: f(x)= 0.30266983072957904
# differential_evolution step 960: f(x)= 0.30266983072957904
# differential_evolution step 961: f(x)= 0.30266983072957904
# differential_evolution step 962: f(x)= 0.30266983072957904
# differential_evolution step 963: f(x)= 0.30266983072957904
# differential_evolution step 964: f(x)= 0.30266983072957904
# differential_evolution step 965: f(x)= 0.30266983072957904
# differential_evolution step 966: f(x)= 0.30266983072957904
# differential_evolution step 967: f(x)= 0.3018083490040524
# differential_evolution step 968: f(x)= 0.3018083490040524
# differential_evolution step 969: f(x)= 0.3018083490040524
# differential_evolution step 970: f(x)= 0.3018083490040524
# differential_evolution step 971: f(x)= 0.3018083490040524
# differential_evolution step 972: f(x)= 0.3018083490040524
# differential_evolution step 973: f(x)= 0.3018083490040524
# differential_evolution step 974: f(x)= 0.3018083490040524
# differential_evolution step 975: f(x)= 0.3018083490040524
# differential_evolution step 976: f(x)= 0.3018083490040524
# differential_evolution step 977: f(x)= 0.3018083490040524
# differential_evolution step 978: f(x)= 0.3018083490040524
# differential_evolution step 979: f(x)= 0.3018083490040524
# differential_evolution step 980: f(x)= 0.3018083490040524
# differential_evolution step 981: f(x)= 0.3018083490040524
# differential_evolution step 982: f(x)= 0.3018083490040524
# differential_evolution step 983: f(x)= 0.3018083490040524
# differential_evolution step 984: f(x)= 0.3018083490040524
# differential_evolution step 985: f(x)= 0.3018083490040524
# differential_evolution step 986: f(x)= 0.30171387623824136
# differential_evolution step 987: f(x)= 0.30171387623824136
# differential_evolution step 988: f(x)= 0.30171387623824136
# differential_evolution step 989: f(x)= 0.30171387623824136
# differential_evolution step 990: f(x)= 0.30171387623824136
# differential_evolution step 991: f(x)= 0.30171387623824136
# differential_evolution step 992: f(x)= 0.30171387623824136
# differential_evolution step 993: f(x)= 0.30171387623824136
# differential_evolution step 994: f(x)= 0.30171387623824136
# differential_evolution step 995: f(x)= 0.30171387623824136
# differential_evolution step 996: f(x)= 0.3006274047934653
# differential_evolution step 997: f(x)= 0.3006274047934653
# differential_evolution step 998: f(x)= 0.3006274047934653
# differential_evolution step 999: f(x)= 0.3006274047934653
# differential_evolution step 1000: f(x)= 0.3006274047934653
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.29432736e-01 2.81347094e+01 1.56767729e+00 5.59736922e+01
#  1.42268662e-01 7.48972202e+00 1.40833707e+00 8.64029852e+01
#  2.35897970e-02 2.41151612e+01 1.74271945e+00 1.48284441e+01
#  1.96614567e-02 1.16553001e+01 2.25395320e+00 3.56489122e+01
#  2.24651486e-01 2.47471320e+00 3.11122672e-01 6.60000000e+01]
# Chi quadro minimo: 0.29407009602965417

# %%
# Plots:
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, 
                                         sigma = radial_profile_error_HA, maxfev = 10000)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\2155415607.py:11: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.3895, r_e=8.8238, n=0.8457, x_0=55.8792
# Sérsic 2: I_e=0.0584, r_e=17.6616, n=2.0140, x_0=86.3322
# Sérsic 3: I_e=0.1788, r_e=3.9322, n=0.3420, x_0=14.5400
# Sérsic 4: I_e=0.0045, r_e=282.0542, n=2.9583, x_0=35.6242
# Sérsic 5: I_e=0.2850, r_e=2.7038, n=0.3694, x_0=67.5594
# [4.81254153e-02 8.78462723e-01 8.42884547e-02 1.57524618e-01
#  3.73311877e-02 9.16420450e+00 4.50715257e-01 1.06368473e-01
#  3.91260291e-02 4.85005471e-01 1.70784942e-01 3.19195169e-01
#  1.20501030e-02 6.60404918e+02 1.86167266e+00 4.12698014e-03
#  9.75940104e-02 4.54510026e-01 2.69496606e-01 2.63054772e-01]
# 7.572720790772392
# 58.20563218317746 7.572720790772392 99.67612451053424 20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (33, 38), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (63, 68),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 65337.23980368523
# differential_evolution step 2: f(x)= 62945.87248122782
# differential_evolution step 3: f(x)= 48740.48747156148
# differential_evolution step 4: f(x)= 45356.99465760828
# differential_evolution step 5: f(x)= 12630.379191849455
# differential_evolution step 6: f(x)= 12630.379191849455
# differential_evolution step 7: f(x)= 9242.776673646316
# differential_evolution step 8: f(x)= 9242.776673646316
# differential_evolution step 9: f(x)= 9242.776673646316
# differential_evolution step 10: f(x)= 9242.776673646316
# differential_evolution step 11: f(x)= 9242.776673646316
# differential_evolution step 12: f(x)= 5532.57353686428
# differential_evolution step 13: f(x)= 5532.57353686428
# differential_evolution step 14: f(x)= 5532.57353686428
# differential_evolution step 15: f(x)= 3625.0366100102115
# differential_evolution step 16: f(x)= 2041.7744652300232
# differential_evolution step 17: f(x)= 2041.7744652300232
# differential_evolution step 18: f(x)= 2041.7744652300232
# differential_evolution step 19: f(x)= 2041.7744652300232
# differential_evolution step 20: f(x)= 2041.7744652300232
# differential_evolution step 21: f(x)= 2041.7744652300232
# differential_evolution step 22: f(x)= 2041.7744652300232
# differential_evolution step 23: f(x)= 2041.7744652300232
# differential_evolution step 24: f(x)= 2041.7744652300232
# differential_evolution step 25: f(x)= 2041.7744652300232
# differential_evolution step 26: f(x)= 1175.2467905625892
# differential_evolution step 27: f(x)= 1175.2467905625892
# differential_evolution step 28: f(x)= 1175.2467905625892
# differential_evolution step 29: f(x)= 1175.2467905625892
# differential_evolution step 30: f(x)= 1175.2467905625892
# differential_evolution step 31: f(x)= 1175.2467905625892
# differential_evolution step 32: f(x)= 1175.2467905625892
# differential_evolution step 33: f(x)= 1175.2467905625892
# differential_evolution step 34: f(x)= 1175.2467905625892
# differential_evolution step 35: f(x)= 1175.2467905625892
# differential_evolution step 36: f(x)= 228.69485792941938
# differential_evolution step 37: f(x)= 228.69485792941938
# differential_evolution step 38: f(x)= 228.69485792941938
# differential_evolution step 39: f(x)= 228.69485792941938
# differential_evolution step 40: f(x)= 228.69485792941938
# differential_evolution step 41: f(x)= 228.69485792941938
# differential_evolution step 42: f(x)= 228.69485792941938
# differential_evolution step 43: f(x)= 228.69485792941938
# differential_evolution step 44: f(x)= 228.69485792941938
# differential_evolution step 45: f(x)= 228.69485792941938
# differential_evolution step 46: f(x)= 228.69485792941938
# differential_evolution step 47: f(x)= 228.69485792941938
# differential_evolution step 48: f(x)= 228.69485792941938
# differential_evolution step 49: f(x)= 228.69485792941938
# differential_evolution step 50: f(x)= 180.71234652666485
# differential_evolution step 51: f(x)= 180.71234652666485
# differential_evolution step 52: f(x)= 180.71234652666485
# differential_evolution step 53: f(x)= 180.71234652666485
# differential_evolution step 54: f(x)= 180.71234652666485
# differential_evolution step 55: f(x)= 180.71234652666485
# differential_evolution step 56: f(x)= 180.71234652666485
# differential_evolution step 57: f(x)= 58.77044951987619
# differential_evolution step 58: f(x)= 25.310080159946093
# differential_evolution step 59: f(x)= 25.310080159946093
# differential_evolution step 60: f(x)= 25.310080159946093
# differential_evolution step 61: f(x)= 25.310080159946093
# differential_evolution step 62: f(x)= 25.310080159946093
# differential_evolution step 63: f(x)= 25.310080159946093
# differential_evolution step 64: f(x)= 25.310080159946093
# differential_evolution step 65: f(x)= 25.310080159946093
# differential_evolution step 66: f(x)= 25.310080159946093
# differential_evolution step 67: f(x)= 25.310080159946093
# differential_evolution step 68: f(x)= 25.310080159946093
# differential_evolution step 69: f(x)= 25.310080159946093
# differential_evolution step 70: f(x)= 25.310080159946093
# differential_evolution step 71: f(x)= 25.310080159946093
# differential_evolution step 72: f(x)= 25.310080159946093
# differential_evolution step 73: f(x)= 25.310080159946093
# differential_evolution step 74: f(x)= 25.310080159946093
# differential_evolution step 75: f(x)= 25.310080159946093
# differential_evolution step 76: f(x)= 25.135092597888107
# differential_evolution step 77: f(x)= 25.135092597888107
# differential_evolution step 78: f(x)= 25.135092597888107
# differential_evolution step 79: f(x)= 25.135092597888107
# differential_evolution step 80: f(x)= 25.135092597888107
# differential_evolution step 81: f(x)= 25.135092597888107
# differential_evolution step 82: f(x)= 21.331300009886753
# differential_evolution step 83: f(x)= 21.331300009886753
# differential_evolution step 84: f(x)= 21.331300009886753
# differential_evolution step 85: f(x)= 20.388665983207847
# differential_evolution step 86: f(x)= 20.388665983207847
# differential_evolution step 87: f(x)= 20.388665983207847
# differential_evolution step 88: f(x)= 12.89312628576668
# differential_evolution step 89: f(x)= 9.429217808589655
# differential_evolution step 90: f(x)= 9.429217808589655
# differential_evolution step 91: f(x)= 8.75489902388436
# differential_evolution step 92: f(x)= 7.416236189731035
# differential_evolution step 93: f(x)= 7.416236189731035
# differential_evolution step 94: f(x)= 7.416236189731035
# differential_evolution step 95: f(x)= 7.416236189731035
# differential_evolution step 96: f(x)= 7.416236189731035
# differential_evolution step 97: f(x)= 4.934991417394237
# differential_evolution step 98: f(x)= 4.934991417394237
# differential_evolution step 99: f(x)= 4.934991417394237
# differential_evolution step 100: f(x)= 4.934991417394237
# differential_evolution step 101: f(x)= 4.934991417394237
# differential_evolution step 102: f(x)= 4.934991417394237
# differential_evolution step 103: f(x)= 4.934991417394237
# differential_evolution step 104: f(x)= 4.934991417394237
# differential_evolution step 105: f(x)= 3.2271440675354937
# differential_evolution step 106: f(x)= 3.2271440675354937
# differential_evolution step 107: f(x)= 3.2271440675354937
# differential_evolution step 108: f(x)= 3.2271440675354937
# differential_evolution step 109: f(x)= 3.2271440675354937
# differential_evolution step 110: f(x)= 3.2271440675354937
# differential_evolution step 111: f(x)= 3.2271440675354937
# differential_evolution step 112: f(x)= 3.2271440675354937
# differential_evolution step 113: f(x)= 3.2271440675354937
# differential_evolution step 114: f(x)= 3.2271440675354937
# differential_evolution step 115: f(x)= 3.2271440675354937
# differential_evolution step 116: f(x)= 3.2271440675354937
# differential_evolution step 117: f(x)= 3.2271440675354937
# differential_evolution step 118: f(x)= 3.2271440675354937
# differential_evolution step 119: f(x)= 3.2271440675354937
# differential_evolution step 120: f(x)= 3.2271440675354937
# differential_evolution step 121: f(x)= 3.2271440675354937
# differential_evolution step 122: f(x)= 3.2271440675354937
# differential_evolution step 123: f(x)= 3.2271440675354937
# differential_evolution step 124: f(x)= 3.2271440675354937
# differential_evolution step 125: f(x)= 3.2271440675354937
# differential_evolution step 126: f(x)= 3.2271440675354937
# differential_evolution step 127: f(x)= 3.2271440675354937
# differential_evolution step 128: f(x)= 2.9259956886706484
# differential_evolution step 129: f(x)= 2.9259956886706484
# differential_evolution step 130: f(x)= 2.9259956886706484
# differential_evolution step 131: f(x)= 2.9259956886706484
# differential_evolution step 132: f(x)= 2.9259956886706484
# differential_evolution step 133: f(x)= 2.9259956886706484
# differential_evolution step 134: f(x)= 2.9259956886706484
# differential_evolution step 135: f(x)= 2.9259956886706484
# differential_evolution step 136: f(x)= 2.9259956886706484
# differential_evolution step 137: f(x)= 2.9259956886706484
# differential_evolution step 138: f(x)= 2.9259956886706484
# differential_evolution step 139: f(x)= 2.9259956886706484
# differential_evolution step 140: f(x)= 2.9259956886706484
# differential_evolution step 141: f(x)= 2.9259956886706484
# differential_evolution step 142: f(x)= 2.9259956886706484
# differential_evolution step 143: f(x)= 2.9259956886706484
# differential_evolution step 144: f(x)= 2.7074722434718526
# differential_evolution step 145: f(x)= 2.7074722434718526
# differential_evolution step 146: f(x)= 2.7074722434718526
# differential_evolution step 147: f(x)= 2.7074722434718526
# differential_evolution step 148: f(x)= 2.7074722434718526
# differential_evolution step 149: f(x)= 2.7074722434718526
# differential_evolution step 150: f(x)= 2.2809593930487777
# differential_evolution step 151: f(x)= 2.2809593930487777
# differential_evolution step 152: f(x)= 2.2809593930487777
# differential_evolution step 153: f(x)= 2.2799027018162716
# differential_evolution step 154: f(x)= 2.2799027018162716
# differential_evolution step 155: f(x)= 2.2799027018162716
# differential_evolution step 156: f(x)= 2.2799027018162716
# differential_evolution step 157: f(x)= 2.2799027018162716
# differential_evolution step 158: f(x)= 2.2799027018162716
# differential_evolution step 159: f(x)= 2.2799027018162716
# differential_evolution step 160: f(x)= 2.2799027018162716
# differential_evolution step 161: f(x)= 2.2799027018162716
# differential_evolution step 162: f(x)= 2.2799027018162716
# differential_evolution step 163: f(x)= 1.6922657465799542
# differential_evolution step 164: f(x)= 1.6922657465799542
# differential_evolution step 165: f(x)= 1.6922657465799542
# differential_evolution step 166: f(x)= 1.6922657465799542
# differential_evolution step 167: f(x)= 1.6922657465799542
# differential_evolution step 168: f(x)= 1.6922657465799542
# differential_evolution step 169: f(x)= 1.6922657465799542
# differential_evolution step 170: f(x)= 1.6922657465799542
# differential_evolution step 171: f(x)= 1.6922657465799542
# differential_evolution step 172: f(x)= 1.6922657465799542
# differential_evolution step 173: f(x)= 1.6096296623508706
# differential_evolution step 174: f(x)= 1.6096296623508706
# differential_evolution step 175: f(x)= 1.6096296623508706
# differential_evolution step 176: f(x)= 1.6096296623508706
# differential_evolution step 177: f(x)= 1.6096296623508706
# differential_evolution step 178: f(x)= 1.6096296623508706
# differential_evolution step 179: f(x)= 1.6096296623508706
# differential_evolution step 180: f(x)= 1.6096296623508706
# differential_evolution step 181: f(x)= 1.6096296623508706
# differential_evolution step 182: f(x)= 1.6096296623508706
# differential_evolution step 183: f(x)= 1.6096296623508706
# differential_evolution step 184: f(x)= 1.6096296623508706
# differential_evolution step 185: f(x)= 1.6096296623508706
# differential_evolution step 186: f(x)= 1.6096296623508706
# differential_evolution step 187: f(x)= 1.6096296623508706
# differential_evolution step 188: f(x)= 1.6096296623508706
# differential_evolution step 189: f(x)= 1.6096296623508706
# differential_evolution step 190: f(x)= 1.6096296623508706
# differential_evolution step 191: f(x)= 1.6096296623508706
# differential_evolution step 192: f(x)= 1.6096296623508706
# differential_evolution step 193: f(x)= 1.2926292879257315
# differential_evolution step 194: f(x)= 1.2926292879257315
# differential_evolution step 195: f(x)= 1.2926292879257315
# differential_evolution step 196: f(x)= 1.2926292879257315
# differential_evolution step 197: f(x)= 1.2926292879257315
# differential_evolution step 198: f(x)= 1.1051480778580722
# differential_evolution step 199: f(x)= 1.1051480778580722
# differential_evolution step 200: f(x)= 1.1051480778580722
# differential_evolution step 201: f(x)= 1.1051480778580722
# differential_evolution step 202: f(x)= 1.1051480778580722
# differential_evolution step 203: f(x)= 1.1051480778580722
# differential_evolution step 204: f(x)= 1.1051480778580722
# differential_evolution step 205: f(x)= 1.1051480778580722
# differential_evolution step 206: f(x)= 1.1051480778580722
# differential_evolution step 207: f(x)= 1.1051480778580722
# differential_evolution step 208: f(x)= 1.05627290607327
# differential_evolution step 209: f(x)= 1.05627290607327
# differential_evolution step 210: f(x)= 1.05627290607327
# differential_evolution step 211: f(x)= 1.05627290607327
# differential_evolution step 212: f(x)= 1.05627290607327
# differential_evolution step 213: f(x)= 1.05627290607327
# differential_evolution step 214: f(x)= 1.05627290607327
# differential_evolution step 215: f(x)= 1.05627290607327
# differential_evolution step 216: f(x)= 1.05627290607327
# differential_evolution step 217: f(x)= 1.05627290607327
# differential_evolution step 218: f(x)= 1.05627290607327
# differential_evolution step 219: f(x)= 1.05627290607327
# differential_evolution step 220: f(x)= 1.05627290607327
# differential_evolution step 221: f(x)= 1.05627290607327
# differential_evolution step 222: f(x)= 1.05627290607327
# differential_evolution step 223: f(x)= 1.05627290607327
# differential_evolution step 224: f(x)= 1.05627290607327
# differential_evolution step 225: f(x)= 1.05627290607327
# differential_evolution step 226: f(x)= 0.922388355844608
# differential_evolution step 227: f(x)= 0.922388355844608
# differential_evolution step 228: f(x)= 0.922388355844608
# differential_evolution step 229: f(x)= 0.922388355844608
# differential_evolution step 230: f(x)= 0.922388355844608
# differential_evolution step 231: f(x)= 0.922388355844608
# differential_evolution step 232: f(x)= 0.922388355844608
# differential_evolution step 233: f(x)= 0.922388355844608
# differential_evolution step 234: f(x)= 0.922388355844608
# differential_evolution step 235: f(x)= 0.922388355844608
# differential_evolution step 236: f(x)= 0.922388355844608
# differential_evolution step 237: f(x)= 0.922388355844608
# differential_evolution step 238: f(x)= 0.922388355844608
# differential_evolution step 239: f(x)= 0.922388355844608
# differential_evolution step 240: f(x)= 0.922388355844608
# differential_evolution step 241: f(x)= 0.922388355844608
# differential_evolution step 242: f(x)= 0.8909099108256544
# differential_evolution step 243: f(x)= 0.8909099108256544
# differential_evolution step 244: f(x)= 0.8254246446530842
# differential_evolution step 245: f(x)= 0.8254246446530842
# differential_evolution step 246: f(x)= 0.8254246446530842
# differential_evolution step 247: f(x)= 0.8254246446530842
# differential_evolution step 248: f(x)= 0.8254246446530842
# differential_evolution step 249: f(x)= 0.8254246446530842
# differential_evolution step 250: f(x)= 0.8254246446530842
# differential_evolution step 251: f(x)= 0.8254246446530842
# differential_evolution step 252: f(x)= 0.8254246446530842
# differential_evolution step 253: f(x)= 0.8254246446530842
# differential_evolution step 254: f(x)= 0.8254246446530842
# differential_evolution step 255: f(x)= 0.8254246446530842
# differential_evolution step 256: f(x)= 0.8254246446530842
# differential_evolution step 257: f(x)= 0.8254246446530842
# differential_evolution step 258: f(x)= 0.8254246446530842
# differential_evolution step 259: f(x)= 0.8254246446530842
# differential_evolution step 260: f(x)= 0.8254246446530842
# differential_evolution step 261: f(x)= 0.8254246446530842
# differential_evolution step 262: f(x)= 0.8254246446530842
# differential_evolution step 263: f(x)= 0.6943144688768792
# differential_evolution step 264: f(x)= 0.6943144688768792
# differential_evolution step 265: f(x)= 0.6943144688768792
# differential_evolution step 266: f(x)= 0.6943144688768792
# differential_evolution step 267: f(x)= 0.6943144688768792
# differential_evolution step 268: f(x)= 0.6943144688768792
# differential_evolution step 269: f(x)= 0.6943144688768792
# differential_evolution step 270: f(x)= 0.6943144688768792
# differential_evolution step 271: f(x)= 0.6943144688768792
# differential_evolution step 272: f(x)= 0.6943144688768792
# differential_evolution step 273: f(x)= 0.6943144688768792
# differential_evolution step 274: f(x)= 0.6943144688768792
# differential_evolution step 275: f(x)= 0.6943144688768792
# differential_evolution step 276: f(x)= 0.6943144688768792
# differential_evolution step 277: f(x)= 0.6754036329192596
# differential_evolution step 278: f(x)= 0.6754036329192596
# differential_evolution step 279: f(x)= 0.6754036329192596
# differential_evolution step 280: f(x)= 0.6289453724649998
# differential_evolution step 281: f(x)= 0.6289453724649998
# differential_evolution step 282: f(x)= 0.6289453724649998
# differential_evolution step 283: f(x)= 0.6289453724649998
# differential_evolution step 284: f(x)= 0.6289453724649998
# differential_evolution step 285: f(x)= 0.6289453724649998
# differential_evolution step 286: f(x)= 0.6289453724649998
# differential_evolution step 287: f(x)= 0.6289453724649998
# differential_evolution step 288: f(x)= 0.6289453724649998
# differential_evolution step 289: f(x)= 0.6289453724649998
# differential_evolution step 290: f(x)= 0.6289453724649998
# differential_evolution step 291: f(x)= 0.6289453724649998
# differential_evolution step 292: f(x)= 0.6289453724649998
# differential_evolution step 293: f(x)= 0.6289453724649998
# differential_evolution step 294: f(x)= 0.6289453724649998
# differential_evolution step 295: f(x)= 0.6289453724649998
# differential_evolution step 296: f(x)= 0.6289453724649998
# differential_evolution step 297: f(x)= 0.6289453724649998
# differential_evolution step 298: f(x)= 0.6289453724649998
# differential_evolution step 299: f(x)= 0.6289453724649998
# differential_evolution step 300: f(x)= 0.6289453724649998
# differential_evolution step 301: f(x)= 0.6289453724649998
# differential_evolution step 302: f(x)= 0.6289453724649998
# differential_evolution step 303: f(x)= 0.6289453724649998
# differential_evolution step 304: f(x)= 0.6289453724649998
# differential_evolution step 305: f(x)= 0.6289453724649998
# differential_evolution step 306: f(x)= 0.6289453724649998
# differential_evolution step 307: f(x)= 0.6289453724649998
# differential_evolution step 308: f(x)= 0.6253027602843081
# differential_evolution step 309: f(x)= 0.6253027602843081
# differential_evolution step 310: f(x)= 0.6253027602843081
# differential_evolution step 311: f(x)= 0.6253027602843081
# differential_evolution step 312: f(x)= 0.6253027602843081
# differential_evolution step 313: f(x)= 0.6253027602843081
# differential_evolution step 314: f(x)= 0.6178197202936812
# differential_evolution step 315: f(x)= 0.6178197202936812
# differential_evolution step 316: f(x)= 0.6178197202936812
# differential_evolution step 317: f(x)= 0.6178197202936812
# differential_evolution step 318: f(x)= 0.5969908091729074
# differential_evolution step 319: f(x)= 0.5969908091729074
# differential_evolution step 320: f(x)= 0.5969908091729074
# differential_evolution step 321: f(x)= 0.5969908091729074
# differential_evolution step 322: f(x)= 0.5969908091729074
# differential_evolution step 323: f(x)= 0.5969908091729074
# differential_evolution step 324: f(x)= 0.5969908091729074
# differential_evolution step 325: f(x)= 0.5969908091729074
# differential_evolution step 326: f(x)= 0.5969908091729074
# differential_evolution step 327: f(x)= 0.5969908091729074
# differential_evolution step 328: f(x)= 0.5969908091729074
# differential_evolution step 329: f(x)= 0.5865442099017768
# differential_evolution step 330: f(x)= 0.5865442099017768
# differential_evolution step 331: f(x)= 0.49690395495550344
# differential_evolution step 332: f(x)= 0.49690395495550344
# differential_evolution step 333: f(x)= 0.48280251622490433
# differential_evolution step 334: f(x)= 0.4720439144425227
# differential_evolution step 335: f(x)= 0.4720439144425227
# differential_evolution step 336: f(x)= 0.4720439144425227
# differential_evolution step 337: f(x)= 0.4720439144425227
# differential_evolution step 338: f(x)= 0.4720439144425227
# differential_evolution step 339: f(x)= 0.4720439144425227
# differential_evolution step 340: f(x)= 0.4720439144425227
# differential_evolution step 341: f(x)= 0.4720439144425227
# differential_evolution step 342: f(x)= 0.4720439144425227
# differential_evolution step 343: f(x)= 0.4720439144425227
# differential_evolution step 344: f(x)= 0.4720439144425227
# differential_evolution step 345: f(x)= 0.4720439144425227
# differential_evolution step 346: f(x)= 0.45004962807368026
# differential_evolution step 347: f(x)= 0.44580749008144216
# differential_evolution step 348: f(x)= 0.44580749008144216
# differential_evolution step 349: f(x)= 0.44580749008144216
# differential_evolution step 350: f(x)= 0.4318984459569924
# differential_evolution step 351: f(x)= 0.4318984459569924
# differential_evolution step 352: f(x)= 0.4318984459569924
# differential_evolution step 353: f(x)= 0.4318984459569924
# differential_evolution step 354: f(x)= 0.4318984459569924
# differential_evolution step 355: f(x)= 0.4274491502707098
# differential_evolution step 356: f(x)= 0.4274491502707098
# differential_evolution step 357: f(x)= 0.4274491502707098
# differential_evolution step 358: f(x)= 0.4274491502707098
# differential_evolution step 359: f(x)= 0.4274491502707098
# differential_evolution step 360: f(x)= 0.4274491502707098
# differential_evolution step 361: f(x)= 0.4274491502707098
# differential_evolution step 362: f(x)= 0.4274491502707098
# differential_evolution step 363: f(x)= 0.4274491502707098
# differential_evolution step 364: f(x)= 0.4274491502707098
# differential_evolution step 365: f(x)= 0.4274491502707098
# differential_evolution step 366: f(x)= 0.4274491502707098
# differential_evolution step 367: f(x)= 0.4274491502707098
# differential_evolution step 368: f(x)= 0.4024422563530684
# differential_evolution step 369: f(x)= 0.4024422563530684
# differential_evolution step 370: f(x)= 0.4024422563530684
# differential_evolution step 371: f(x)= 0.4024422563530684
# differential_evolution step 372: f(x)= 0.4024422563530684
# differential_evolution step 373: f(x)= 0.4024422563530684
# differential_evolution step 374: f(x)= 0.4024422563530684
# differential_evolution step 375: f(x)= 0.4024422563530684
# differential_evolution step 376: f(x)= 0.4024422563530684
# differential_evolution step 377: f(x)= 0.4024422563530684
# differential_evolution step 378: f(x)= 0.4024422563530684
# differential_evolution step 379: f(x)= 0.4024422563530684
# differential_evolution step 380: f(x)= 0.4024422563530684
# differential_evolution step 381: f(x)= 0.4024422563530684
# differential_evolution step 382: f(x)= 0.3991224025877254
# differential_evolution step 383: f(x)= 0.3812453301553234
# differential_evolution step 384: f(x)= 0.3812453301553234
# differential_evolution step 385: f(x)= 0.3812453301553234
# differential_evolution step 386: f(x)= 0.3812453301553234
# differential_evolution step 387: f(x)= 0.3812453301553234
# differential_evolution step 388: f(x)= 0.3812453301553234
# differential_evolution step 389: f(x)= 0.3812453301553234
# differential_evolution step 390: f(x)= 0.3812453301553234
# differential_evolution step 391: f(x)= 0.3812453301553234
# differential_evolution step 392: f(x)= 0.3812453301553234
# differential_evolution step 393: f(x)= 0.3812453301553234
# differential_evolution step 394: f(x)= 0.3812453301553234
# differential_evolution step 395: f(x)= 0.3812453301553234
# differential_evolution step 396: f(x)= 0.3812453301553234
# differential_evolution step 397: f(x)= 0.35646483169034726
# differential_evolution step 398: f(x)= 0.35646483169034726
# differential_evolution step 399: f(x)= 0.35646483169034726
# differential_evolution step 400: f(x)= 0.35646483169034726
# differential_evolution step 401: f(x)= 0.35646483169034726
# differential_evolution step 402: f(x)= 0.35646483169034726
# differential_evolution step 403: f(x)= 0.35646483169034726
# differential_evolution step 404: f(x)= 0.35646483169034726
# differential_evolution step 405: f(x)= 0.35646483169034726
# differential_evolution step 406: f(x)= 0.35646483169034726
# differential_evolution step 407: f(x)= 0.34174659005594227
# differential_evolution step 408: f(x)= 0.34174659005594227
# differential_evolution step 409: f(x)= 0.34174659005594227
# differential_evolution step 410: f(x)= 0.34174659005594227
# differential_evolution step 411: f(x)= 0.34174659005594227
# differential_evolution step 412: f(x)= 0.34174659005594227
# differential_evolution step 413: f(x)= 0.33836826258711433
# differential_evolution step 414: f(x)= 0.3256440127568912
# differential_evolution step 415: f(x)= 0.3256440127568912
# differential_evolution step 416: f(x)= 0.3256440127568912
# differential_evolution step 417: f(x)= 0.3256440127568912
# differential_evolution step 418: f(x)= 0.3256440127568912
# differential_evolution step 419: f(x)= 0.3256440127568912
# differential_evolution step 420: f(x)= 0.32234147240831357
# differential_evolution step 421: f(x)= 0.2891793564993685
# differential_evolution step 422: f(x)= 0.2891793564993685
# differential_evolution step 423: f(x)= 0.2891793564993685
# differential_evolution step 424: f(x)= 0.2891793564993685
# differential_evolution step 425: f(x)= 0.2891793564993685
# differential_evolution step 426: f(x)= 0.2663747414594012
# differential_evolution step 427: f(x)= 0.2663747414594012
# differential_evolution step 428: f(x)= 0.2663747414594012
# differential_evolution step 429: f(x)= 0.2663747414594012
# differential_evolution step 430: f(x)= 0.2663747414594012
# differential_evolution step 431: f(x)= 0.2663747414594012
# differential_evolution step 432: f(x)= 0.2663747414594012
# differential_evolution step 433: f(x)= 0.2663747414594012
# differential_evolution step 434: f(x)= 0.2663747414594012
# differential_evolution step 435: f(x)= 0.2663747414594012
# differential_evolution step 436: f(x)= 0.2663747414594012
# differential_evolution step 437: f(x)= 0.2663747414594012
# differential_evolution step 438: f(x)= 0.2663747414594012
# differential_evolution step 439: f(x)= 0.2663747414594012
# differential_evolution step 440: f(x)= 0.2663747414594012
# differential_evolution step 441: f(x)= 0.2663747414594012
# differential_evolution step 442: f(x)= 0.2663747414594012
# differential_evolution step 443: f(x)= 0.2663747414594012
# differential_evolution step 444: f(x)= 0.2663747414594012
# differential_evolution step 445: f(x)= 0.2663747414594012
# differential_evolution step 446: f(x)= 0.2663747414594012
# differential_evolution step 447: f(x)= 0.2663747414594012
# differential_evolution step 448: f(x)= 0.2663747414594012
# differential_evolution step 449: f(x)= 0.2663747414594012
# differential_evolution step 450: f(x)= 0.2663747414594012
# differential_evolution step 451: f(x)= 0.2663747414594012
# differential_evolution step 452: f(x)= 0.2663747414594012
# differential_evolution step 453: f(x)= 0.2663747414594012
# differential_evolution step 454: f(x)= 0.25846789676061954
# differential_evolution step 455: f(x)= 0.25846789676061954
# differential_evolution step 456: f(x)= 0.25846789676061954
# differential_evolution step 457: f(x)= 0.25846789676061954
# differential_evolution step 458: f(x)= 0.25846789676061954
# differential_evolution step 459: f(x)= 0.25846789676061954
# differential_evolution step 460: f(x)= 0.25846789676061954
# differential_evolution step 461: f(x)= 0.25846789676061954
# differential_evolution step 462: f(x)= 0.25846789676061954
# differential_evolution step 463: f(x)= 0.2501301410929366
# differential_evolution step 464: f(x)= 0.2501301410929366
# differential_evolution step 465: f(x)= 0.2501301410929366
# differential_evolution step 466: f(x)= 0.2501301410929366
# differential_evolution step 467: f(x)= 0.2501301410929366
# differential_evolution step 468: f(x)= 0.2501301410929366
# differential_evolution step 469: f(x)= 0.2501301410929366
# differential_evolution step 470: f(x)= 0.2501301410929366
# differential_evolution step 471: f(x)= 0.2501301410929366
# differential_evolution step 472: f(x)= 0.2501301410929366
# differential_evolution step 473: f(x)= 0.2501301410929366
# differential_evolution step 474: f(x)= 0.2501301410929366
# differential_evolution step 475: f(x)= 0.2501301410929366
# differential_evolution step 476: f(x)= 0.2501301410929366
# differential_evolution step 477: f(x)= 0.2501301410929366
# differential_evolution step 478: f(x)= 0.2501301410929366
# differential_evolution step 479: f(x)= 0.2501301410929366
# differential_evolution step 480: f(x)= 0.24815136091885975
# differential_evolution step 481: f(x)= 0.24587478219529943
# differential_evolution step 482: f(x)= 0.24587478219529943
# differential_evolution step 483: f(x)= 0.2448983644539021
# differential_evolution step 484: f(x)= 0.2448983644539021
# differential_evolution step 485: f(x)= 0.2448983644539021
# differential_evolution step 486: f(x)= 0.2417981142120318
# differential_evolution step 487: f(x)= 0.2417981142120318
# differential_evolution step 488: f(x)= 0.2417981142120318
# differential_evolution step 489: f(x)= 0.23201119388528293
# differential_evolution step 490: f(x)= 0.23201119388528293
# differential_evolution step 491: f(x)= 0.23201119388528293
# differential_evolution step 492: f(x)= 0.23201119388528293
# differential_evolution step 493: f(x)= 0.2305563507810699
# differential_evolution step 494: f(x)= 0.2305563507810699
# differential_evolution step 495: f(x)= 0.2305563507810699
# differential_evolution step 496: f(x)= 0.2305563507810699
# differential_evolution step 497: f(x)= 0.2305563507810699
# differential_evolution step 498: f(x)= 0.2305563507810699
# differential_evolution step 499: f(x)= 0.2305563507810699
# differential_evolution step 500: f(x)= 0.2305563507810699
# differential_evolution step 501: f(x)= 0.21815255545031453
# differential_evolution step 502: f(x)= 0.21815255545031453
# differential_evolution step 503: f(x)= 0.21815255545031453
# differential_evolution step 504: f(x)= 0.21815255545031453
# differential_evolution step 505: f(x)= 0.21815255545031453
# differential_evolution step 506: f(x)= 0.21815255545031453
# differential_evolution step 507: f(x)= 0.21815255545031453
# differential_evolution step 508: f(x)= 0.21815255545031453
# differential_evolution step 509: f(x)= 0.21815255545031453
# differential_evolution step 510: f(x)= 0.21815255545031453
# differential_evolution step 511: f(x)= 0.21815255545031453
# differential_evolution step 512: f(x)= 0.21815255545031453
# differential_evolution step 513: f(x)= 0.21815255545031453
# differential_evolution step 514: f(x)= 0.21815255545031453
# differential_evolution step 515: f(x)= 0.21815255545031453
# differential_evolution step 516: f(x)= 0.21322142462865218
# differential_evolution step 517: f(x)= 0.21322142462865218
# differential_evolution step 518: f(x)= 0.21322142462865218
# differential_evolution step 519: f(x)= 0.21322142462865218
# differential_evolution step 520: f(x)= 0.21322142462865218
# differential_evolution step 521: f(x)= 0.21322142462865218
# differential_evolution step 522: f(x)= 0.21322142462865218
# differential_evolution step 523: f(x)= 0.21322142462865218
# differential_evolution step 524: f(x)= 0.21322142462865218
# differential_evolution step 525: f(x)= 0.21322142462865218
# differential_evolution step 526: f(x)= 0.21322142462865218
# differential_evolution step 527: f(x)= 0.21322142462865218
# differential_evolution step 528: f(x)= 0.21322142462865218
# differential_evolution step 529: f(x)= 0.21322142462865218
# differential_evolution step 530: f(x)= 0.21322142462865218
# differential_evolution step 531: f(x)= 0.21322142462865218
# differential_evolution step 532: f(x)= 0.21322142462865218
# differential_evolution step 533: f(x)= 0.21322142462865218
# differential_evolution step 534: f(x)= 0.21322142462865218
# differential_evolution step 535: f(x)= 0.21322142462865218
# differential_evolution step 536: f(x)= 0.21322142462865218
# differential_evolution step 537: f(x)= 0.21322142462865218
# differential_evolution step 538: f(x)= 0.21322142462865218
# differential_evolution step 539: f(x)= 0.21322142462865218
# differential_evolution step 540: f(x)= 0.21322142462865218
# differential_evolution step 541: f(x)= 0.21322142462865218
# differential_evolution step 542: f(x)= 0.21093435045179884
# differential_evolution step 543: f(x)= 0.21093435045179884
# differential_evolution step 544: f(x)= 0.21093435045179884
# differential_evolution step 545: f(x)= 0.21093435045179884
# differential_evolution step 546: f(x)= 0.21093435045179884
# differential_evolution step 547: f(x)= 0.21093435045179884
# differential_evolution step 548: f(x)= 0.21093435045179884
# differential_evolution step 549: f(x)= 0.21093435045179884
# differential_evolution step 550: f(x)= 0.21093435045179884
# differential_evolution step 551: f(x)= 0.21093435045179884
# differential_evolution step 552: f(x)= 0.21093435045179884
# differential_evolution step 553: f(x)= 0.21093435045179884
# differential_evolution step 554: f(x)= 0.21093435045179884
# differential_evolution step 555: f(x)= 0.21093435045179884
# differential_evolution step 556: f(x)= 0.21093435045179884
# differential_evolution step 557: f(x)= 0.21093435045179884
# differential_evolution step 558: f(x)= 0.21093435045179884
# differential_evolution step 559: f(x)= 0.21093435045179884
# differential_evolution step 560: f(x)= 0.21093435045179884
# differential_evolution step 561: f(x)= 0.21093435045179884
# differential_evolution step 562: f(x)= 0.21093435045179884
# differential_evolution step 563: f(x)= 0.2063064453280602
# differential_evolution step 564: f(x)= 0.2063064453280602
# differential_evolution step 565: f(x)= 0.2063064453280602
# differential_evolution step 566: f(x)= 0.2063064453280602
# differential_evolution step 567: f(x)= 0.2063064453280602
# differential_evolution step 568: f(x)= 0.2063064453280602
# differential_evolution step 569: f(x)= 0.2063064453280602
# differential_evolution step 570: f(x)= 0.2063064453280602
# differential_evolution step 571: f(x)= 0.2063064453280602
# differential_evolution step 572: f(x)= 0.2063064453280602
# differential_evolution step 573: f(x)= 0.2063064453280602
# differential_evolution step 574: f(x)= 0.2063064453280602
# differential_evolution step 575: f(x)= 0.2063064453280602
# differential_evolution step 576: f(x)= 0.2063064453280602
# differential_evolution step 577: f(x)= 0.2063064453280602
# differential_evolution step 578: f(x)= 0.2063064453280602
# differential_evolution step 579: f(x)= 0.1991236141320144
# differential_evolution step 580: f(x)= 0.1991236141320144
# differential_evolution step 581: f(x)= 0.1991236141320144
# differential_evolution step 582: f(x)= 0.1991236141320144
# differential_evolution step 583: f(x)= 0.1991236141320144
# differential_evolution step 584: f(x)= 0.1991236141320144
# differential_evolution step 585: f(x)= 0.1991236141320144
# differential_evolution step 586: f(x)= 0.1991236141320144
# differential_evolution step 587: f(x)= 0.1991236141320144
# differential_evolution step 588: f(x)= 0.1991236141320144
# differential_evolution step 589: f(x)= 0.1991236141320144
# differential_evolution step 590: f(x)= 0.1991236141320144
# differential_evolution step 591: f(x)= 0.1991236141320144
# differential_evolution step 592: f(x)= 0.1991236141320144
# differential_evolution step 593: f(x)= 0.1991236141320144
# differential_evolution step 594: f(x)= 0.1991236141320144
# differential_evolution step 595: f(x)= 0.1991236141320144
# differential_evolution step 596: f(x)= 0.1991236141320144
# differential_evolution step 597: f(x)= 0.1991236141320144
# differential_evolution step 598: f(x)= 0.1991236141320144
# differential_evolution step 599: f(x)= 0.1991236141320144
# differential_evolution step 600: f(x)= 0.1991236141320144
# differential_evolution step 601: f(x)= 0.1991236141320144
# differential_evolution step 602: f(x)= 0.1991236141320144
# differential_evolution step 603: f(x)= 0.1991236141320144
# differential_evolution step 604: f(x)= 0.1991236141320144
# differential_evolution step 605: f(x)= 0.1991236141320144
# differential_evolution step 606: f(x)= 0.1991236141320144
# differential_evolution step 607: f(x)= 0.1991236141320144
# differential_evolution step 608: f(x)= 0.1991236141320144
# differential_evolution step 609: f(x)= 0.1991236141320144
# differential_evolution step 610: f(x)= 0.1991236141320144
# differential_evolution step 611: f(x)= 0.1991236141320144
# differential_evolution step 612: f(x)= 0.1991236141320144
# differential_evolution step 613: f(x)= 0.1991236141320144
# differential_evolution step 614: f(x)= 0.1991236141320144
# differential_evolution step 615: f(x)= 0.19401919047196922
# differential_evolution step 616: f(x)= 0.18638243150757638
# differential_evolution step 617: f(x)= 0.18638243150757638
# differential_evolution step 618: f(x)= 0.18638243150757638
# differential_evolution step 619: f(x)= 0.18638243150757638
# differential_evolution step 620: f(x)= 0.18638243150757638
# differential_evolution step 621: f(x)= 0.18638243150757638
# differential_evolution step 622: f(x)= 0.18638243150757638
# differential_evolution step 623: f(x)= 0.18638243150757638
# differential_evolution step 624: f(x)= 0.18638243150757638
# differential_evolution step 625: f(x)= 0.18638243150757638
# differential_evolution step 626: f(x)= 0.18638243150757638
# differential_evolution step 627: f(x)= 0.18638243150757638
# differential_evolution step 628: f(x)= 0.18638243150757638
# differential_evolution step 629: f(x)= 0.18638243150757638
# differential_evolution step 630: f(x)= 0.18638243150757638
# differential_evolution step 631: f(x)= 0.18638243150757638
# differential_evolution step 632: f(x)= 0.18638243150757638
# differential_evolution step 633: f(x)= 0.18638243150757638
# differential_evolution step 634: f(x)= 0.18638243150757638
# differential_evolution step 635: f(x)= 0.18638243150757638
# differential_evolution step 636: f(x)= 0.18638243150757638
# differential_evolution step 637: f(x)= 0.18638243150757638
# differential_evolution step 638: f(x)= 0.18638243150757638
# differential_evolution step 639: f(x)= 0.18638243150757638
# differential_evolution step 640: f(x)= 0.18638243150757638
# differential_evolution step 641: f(x)= 0.18638243150757638
# differential_evolution step 642: f(x)= 0.18638243150757638
# differential_evolution step 643: f(x)= 0.18638243150757638
# differential_evolution step 644: f(x)= 0.18638243150757638
# differential_evolution step 645: f(x)= 0.18638243150757638
# differential_evolution step 646: f(x)= 0.18638243150757638
# differential_evolution step 647: f(x)= 0.18638243150757638
# differential_evolution step 648: f(x)= 0.18638243150757638
# differential_evolution step 649: f(x)= 0.18638243150757638
# differential_evolution step 650: f(x)= 0.18638243150757638
# differential_evolution step 651: f(x)= 0.18638243150757638
# differential_evolution step 652: f(x)= 0.18548216635765918
# differential_evolution step 653: f(x)= 0.18548216635765918
# differential_evolution step 654: f(x)= 0.18548216635765918
# differential_evolution step 655: f(x)= 0.18548216635765918
# differential_evolution step 656: f(x)= 0.18548216635765918
# differential_evolution step 657: f(x)= 0.18548216635765918
# differential_evolution step 658: f(x)= 0.18548216635765918
# differential_evolution step 659: f(x)= 0.18548216635765918
# differential_evolution step 660: f(x)= 0.18548216635765918
# differential_evolution step 661: f(x)= 0.18548216635765918
# differential_evolution step 662: f(x)= 0.18548216635765918
# differential_evolution step 663: f(x)= 0.18548216635765918
# differential_evolution step 664: f(x)= 0.18548216635765918
# differential_evolution step 665: f(x)= 0.18548216635765918
# differential_evolution step 666: f(x)= 0.18498154673606182
# differential_evolution step 667: f(x)= 0.18498154673606182
# differential_evolution step 668: f(x)= 0.18498154673606182
# differential_evolution step 669: f(x)= 0.18498154673606182
# differential_evolution step 670: f(x)= 0.18498154673606182
# differential_evolution step 671: f(x)= 0.18498154673606182
# differential_evolution step 672: f(x)= 0.18498154673606182
# differential_evolution step 673: f(x)= 0.18498154673606182
# differential_evolution step 674: f(x)= 0.18498154673606182
# differential_evolution step 675: f(x)= 0.18498154673606182
# differential_evolution step 676: f(x)= 0.18447627623670237
# differential_evolution step 677: f(x)= 0.18447627623670237
# differential_evolution step 678: f(x)= 0.18447627623670237
# differential_evolution step 679: f(x)= 0.18447627623670237
# differential_evolution step 680: f(x)= 0.18447627623670237
# differential_evolution step 681: f(x)= 0.18447627623670237
# differential_evolution step 682: f(x)= 0.18447627623670237
# differential_evolution step 683: f(x)= 0.18447627623670237
# differential_evolution step 684: f(x)= 0.18447627623670237
# differential_evolution step 685: f(x)= 0.18447627623670237
# differential_evolution step 686: f(x)= 0.18447627623670237
# differential_evolution step 687: f(x)= 0.18447627623670237
# differential_evolution step 688: f(x)= 0.18447627623670237
# differential_evolution step 689: f(x)= 0.18447627623670237
# differential_evolution step 690: f(x)= 0.18447627623670237
# differential_evolution step 691: f(x)= 0.18447627623670237
# differential_evolution step 692: f(x)= 0.18447627623670237
# differential_evolution step 693: f(x)= 0.18447627623670237
# differential_evolution step 694: f(x)= 0.18447627623670237
# differential_evolution step 695: f(x)= 0.18447627623670237
# differential_evolution step 696: f(x)= 0.18447627623670237
# differential_evolution step 697: f(x)= 0.18447627623670237
# differential_evolution step 698: f(x)= 0.18447627623670237
# differential_evolution step 699: f(x)= 0.18447627623670237
# differential_evolution step 700: f(x)= 0.18447627623670237
# differential_evolution step 701: f(x)= 0.18447627623670237
# differential_evolution step 702: f(x)= 0.18447627623670237
# differential_evolution step 703: f(x)= 0.18447627623670237
# differential_evolution step 704: f(x)= 0.18447627623670237
# differential_evolution step 705: f(x)= 0.18447627623670237
# differential_evolution step 706: f(x)= 0.18447627623670237
# differential_evolution step 707: f(x)= 0.18447627623670237
# differential_evolution step 708: f(x)= 0.18447627623670237
# differential_evolution step 709: f(x)= 0.18447627623670237
# differential_evolution step 710: f(x)= 0.18447627623670237
# differential_evolution step 711: f(x)= 0.18447627623670237
# differential_evolution step 712: f(x)= 0.18447627623670237
# differential_evolution step 713: f(x)= 0.18447627623670237
# differential_evolution step 714: f(x)= 0.18447627623670237
# differential_evolution step 715: f(x)= 0.18447627623670237
# differential_evolution step 716: f(x)= 0.18447627623670237
# differential_evolution step 717: f(x)= 0.18447627623670237
# differential_evolution step 718: f(x)= 0.18447627623670237
# differential_evolution step 719: f(x)= 0.18447627623670237
# differential_evolution step 720: f(x)= 0.18447627623670237
# differential_evolution step 721: f(x)= 0.18447627623670237
# differential_evolution step 722: f(x)= 0.18447627623670237
# differential_evolution step 723: f(x)= 0.18447627623670237
# differential_evolution step 724: f(x)= 0.18447627623670237
# differential_evolution step 725: f(x)= 0.18447627623670237
# differential_evolution step 726: f(x)= 0.18447627623670237
# differential_evolution step 727: f(x)= 0.18447627623670237
# differential_evolution step 728: f(x)= 0.18447627623670237
# differential_evolution step 729: f(x)= 0.18447627623670237
# differential_evolution step 730: f(x)= 0.18447627623670237
# differential_evolution step 731: f(x)= 0.18447627623670237
# differential_evolution step 732: f(x)= 0.18447627623670237
# differential_evolution step 733: f(x)= 0.18447627623670237
# differential_evolution step 734: f(x)= 0.18447627623670237
# differential_evolution step 735: f(x)= 0.18447627623670237
# differential_evolution step 736: f(x)= 0.18447627623670237
# differential_evolution step 737: f(x)= 0.18447627623670237
# differential_evolution step 738: f(x)= 0.18447627623670237
# differential_evolution step 739: f(x)= 0.18447627623670237
# differential_evolution step 740: f(x)= 0.18447627623670237
# differential_evolution step 741: f(x)= 0.18447627623670237
# differential_evolution step 742: f(x)= 0.18447627623670237
# differential_evolution step 743: f(x)= 0.18447627623670237
# differential_evolution step 744: f(x)= 0.18447627623670237
# differential_evolution step 745: f(x)= 0.18447627623670237
# differential_evolution step 746: f(x)= 0.18447627623670237
# differential_evolution step 747: f(x)= 0.18447627623670237
# differential_evolution step 748: f(x)= 0.18447627623670237
# differential_evolution step 749: f(x)= 0.18447627623670237
# differential_evolution step 750: f(x)= 0.18447627623670237
# differential_evolution step 751: f(x)= 0.18447627623670237
# differential_evolution step 752: f(x)= 0.18447627623670237
# differential_evolution step 753: f(x)= 0.18447627623670237
# differential_evolution step 754: f(x)= 0.18447627623670237
# differential_evolution step 755: f(x)= 0.18447627623670237
# differential_evolution step 756: f(x)= 0.18447627623670237
# differential_evolution step 757: f(x)= 0.18447627623670237
# differential_evolution step 758: f(x)= 0.18447627623670237
# differential_evolution step 759: f(x)= 0.18447627623670237
# differential_evolution step 760: f(x)= 0.18447627623670237
# differential_evolution step 761: f(x)= 0.18447627623670237
# differential_evolution step 762: f(x)= 0.18447627623670237
# differential_evolution step 763: f(x)= 0.18447627623670237
# differential_evolution step 764: f(x)= 0.18447627623670237
# differential_evolution step 765: f(x)= 0.18447627623670237
# differential_evolution step 766: f(x)= 0.18447627623670237
# differential_evolution step 767: f(x)= 0.18447627623670237
# differential_evolution step 768: f(x)= 0.18447627623670237
# differential_evolution step 769: f(x)= 0.18447627623670237
# differential_evolution step 770: f(x)= 0.18447627623670237
# differential_evolution step 771: f(x)= 0.18143252346293184
# differential_evolution step 772: f(x)= 0.18143252346293184
# differential_evolution step 773: f(x)= 0.18143252346293184
# differential_evolution step 774: f(x)= 0.18143252346293184
# differential_evolution step 775: f(x)= 0.18143252346293184
# differential_evolution step 776: f(x)= 0.18143252346293184
# differential_evolution step 777: f(x)= 0.18143252346293184
# differential_evolution step 778: f(x)= 0.18143252346293184
# differential_evolution step 779: f(x)= 0.18143252346293184
# differential_evolution step 780: f(x)= 0.18143252346293184
# differential_evolution step 781: f(x)= 0.18143252346293184
# differential_evolution step 782: f(x)= 0.18143252346293184
# differential_evolution step 783: f(x)= 0.18143252346293184
# differential_evolution step 784: f(x)= 0.18143252346293184
# differential_evolution step 785: f(x)= 0.18143252346293184
# differential_evolution step 786: f(x)= 0.18143252346293184
# differential_evolution step 787: f(x)= 0.18143252346293184
# differential_evolution step 788: f(x)= 0.18143252346293184
# differential_evolution step 789: f(x)= 0.18143252346293184
# differential_evolution step 790: f(x)= 0.18143252346293184
# differential_evolution step 791: f(x)= 0.18143252346293184
# differential_evolution step 792: f(x)= 0.18143252346293184
# differential_evolution step 793: f(x)= 0.18143252346293184
# differential_evolution step 794: f(x)= 0.18143252346293184
# differential_evolution step 795: f(x)= 0.18143252346293184
# differential_evolution step 796: f(x)= 0.18143252346293184
# differential_evolution step 797: f(x)= 0.18143252346293184
# differential_evolution step 798: f(x)= 0.1791950537963371
# differential_evolution step 799: f(x)= 0.1791950537963371
# differential_evolution step 800: f(x)= 0.1791950537963371
# differential_evolution step 801: f(x)= 0.1791950537963371
# differential_evolution step 802: f(x)= 0.1791950537963371
# differential_evolution step 803: f(x)= 0.1791950537963371
# differential_evolution step 804: f(x)= 0.1791950537963371
# differential_evolution step 805: f(x)= 0.1791950537963371
# differential_evolution step 806: f(x)= 0.1791950537963371
# differential_evolution step 807: f(x)= 0.1791950537963371
# differential_evolution step 808: f(x)= 0.1791950537963371
# differential_evolution step 809: f(x)= 0.1791950537963371
# differential_evolution step 810: f(x)= 0.1791950537963371
# differential_evolution step 811: f(x)= 0.1762479747979169
# differential_evolution step 812: f(x)= 0.1762479747979169
# differential_evolution step 813: f(x)= 0.1762479747979169
# differential_evolution step 814: f(x)= 0.1762479747979169
# differential_evolution step 815: f(x)= 0.1762479747979169
# differential_evolution step 816: f(x)= 0.1762479747979169
# differential_evolution step 817: f(x)= 0.1762479747979169
# differential_evolution step 818: f(x)= 0.1762479747979169
# differential_evolution step 819: f(x)= 0.1762479747979169
# differential_evolution step 820: f(x)= 0.1762479747979169
# differential_evolution step 821: f(x)= 0.1762479747979169
# differential_evolution step 822: f(x)= 0.1762479747979169
# differential_evolution step 823: f(x)= 0.1762479747979169
# differential_evolution step 824: f(x)= 0.1762479747979169
# differential_evolution step 825: f(x)= 0.1762479747979169
# differential_evolution step 826: f(x)= 0.1762479747979169
# differential_evolution step 827: f(x)= 0.1751931638928696
# differential_evolution step 828: f(x)= 0.1751931638928696
# differential_evolution step 829: f(x)= 0.1751931638928696
# differential_evolution step 830: f(x)= 0.1751931638928696
# differential_evolution step 831: f(x)= 0.1751931638928696
# differential_evolution step 832: f(x)= 0.1751931638928696
# differential_evolution step 833: f(x)= 0.1751931638928696
# differential_evolution step 834: f(x)= 0.1751931638928696
# differential_evolution step 835: f(x)= 0.1751931638928696
# differential_evolution step 836: f(x)= 0.1751931638928696
# differential_evolution step 837: f(x)= 0.1751931638928696
# differential_evolution step 838: f(x)= 0.1751931638928696
# differential_evolution step 839: f(x)= 0.1740149204089755
# differential_evolution step 840: f(x)= 0.1740149204089755
# differential_evolution step 841: f(x)= 0.1740149204089755
# differential_evolution step 842: f(x)= 0.1740149204089755
# differential_evolution step 843: f(x)= 0.1740149204089755
# differential_evolution step 844: f(x)= 0.1740149204089755
# differential_evolution step 845: f(x)= 0.1740149204089755
# differential_evolution step 846: f(x)= 0.1740149204089755
# differential_evolution step 847: f(x)= 0.1740149204089755
# differential_evolution step 848: f(x)= 0.1740149204089755
# differential_evolution step 849: f(x)= 0.1740149204089755
# differential_evolution step 850: f(x)= 0.1740149204089755
# differential_evolution step 851: f(x)= 0.1740149204089755
# differential_evolution step 852: f(x)= 0.1740149204089755
# differential_evolution step 853: f(x)= 0.1740149204089755
# differential_evolution step 854: f(x)= 0.1740149204089755
# differential_evolution step 855: f(x)= 0.1740149204089755
# differential_evolution step 856: f(x)= 0.1740149204089755
# differential_evolution step 857: f(x)= 0.1740149204089755
# differential_evolution step 858: f(x)= 0.1740149204089755
# differential_evolution step 859: f(x)= 0.1740149204089755
# differential_evolution step 860: f(x)= 0.1740149204089755
# differential_evolution step 861: f(x)= 0.1740149204089755
# differential_evolution step 862: f(x)= 0.1740149204089755
# differential_evolution step 863: f(x)= 0.1740149204089755
# differential_evolution step 864: f(x)= 0.1740149204089755
# differential_evolution step 865: f(x)= 0.1740149204089755
# differential_evolution step 866: f(x)= 0.1740149204089755
# differential_evolution step 867: f(x)= 0.1740149204089755
# differential_evolution step 868: f(x)= 0.1740149204089755
# differential_evolution step 869: f(x)= 0.1740149204089755
# differential_evolution step 870: f(x)= 0.1740149204089755
# differential_evolution step 871: f(x)= 0.1740149204089755
# differential_evolution step 872: f(x)= 0.1740149204089755
# differential_evolution step 873: f(x)= 0.1740149204089755
# differential_evolution step 874: f(x)= 0.1740149204089755
# differential_evolution step 875: f(x)= 0.1740149204089755
# differential_evolution step 876: f(x)= 0.1740149204089755
# differential_evolution step 877: f(x)= 0.1740149204089755
# differential_evolution step 878: f(x)= 0.1740149204089755
# differential_evolution step 879: f(x)= 0.1740149204089755
# differential_evolution step 880: f(x)= 0.1740149204089755
# differential_evolution step 881: f(x)= 0.1740149204089755
# differential_evolution step 882: f(x)= 0.1740149204089755
# differential_evolution step 883: f(x)= 0.1740149204089755
# differential_evolution step 884: f(x)= 0.1740149204089755
# differential_evolution step 885: f(x)= 0.1740149204089755
# differential_evolution step 886: f(x)= 0.1740149204089755
# differential_evolution step 887: f(x)= 0.1740149204089755
# differential_evolution step 888: f(x)= 0.1740149204089755
# differential_evolution step 889: f(x)= 0.1740149204089755
# differential_evolution step 890: f(x)= 0.1740149204089755
# differential_evolution step 891: f(x)= 0.1740149204089755
# differential_evolution step 892: f(x)= 0.1740149204089755
# differential_evolution step 893: f(x)= 0.1740149204089755
# differential_evolution step 894: f(x)= 0.1740149204089755
# differential_evolution step 895: f(x)= 0.1740149204089755
# differential_evolution step 896: f(x)= 0.17317653055884652
# differential_evolution step 897: f(x)= 0.17317653055884652
# differential_evolution step 898: f(x)= 0.17317653055884652
# differential_evolution step 899: f(x)= 0.17317653055884652
# differential_evolution step 900: f(x)= 0.17317653055884652
# differential_evolution step 901: f(x)= 0.17317653055884652
# differential_evolution step 902: f(x)= 0.17317653055884652
# differential_evolution step 903: f(x)= 0.17317653055884652
# differential_evolution step 904: f(x)= 0.17317653055884652
# differential_evolution step 905: f(x)= 0.17317653055884652
# differential_evolution step 906: f(x)= 0.17317653055884652
# differential_evolution step 907: f(x)= 0.17317653055884652
# differential_evolution step 908: f(x)= 0.17317653055884652
# differential_evolution step 909: f(x)= 0.17317653055884652
# differential_evolution step 910: f(x)= 0.17317653055884652
# differential_evolution step 911: f(x)= 0.17317653055884652
# differential_evolution step 912: f(x)= 0.17317653055884652
# differential_evolution step 913: f(x)= 0.17317653055884652
# differential_evolution step 914: f(x)= 0.17317653055884652
# differential_evolution step 915: f(x)= 0.17317653055884652
# differential_evolution step 916: f(x)= 0.17317653055884652
# differential_evolution step 917: f(x)= 0.17317653055884652
# differential_evolution step 918: f(x)= 0.17317653055884652
# differential_evolution step 919: f(x)= 0.17317653055884652
# differential_evolution step 920: f(x)= 0.17317653055884652
# differential_evolution step 921: f(x)= 0.17317653055884652
# differential_evolution step 922: f(x)= 0.17317653055884652
# differential_evolution step 923: f(x)= 0.17317653055884652
# differential_evolution step 924: f(x)= 0.17317653055884652
# differential_evolution step 925: f(x)= 0.17317653055884652
# differential_evolution step 926: f(x)= 0.17259296888837952
# differential_evolution step 927: f(x)= 0.17259296888837952
# differential_evolution step 928: f(x)= 0.17259296888837952
# differential_evolution step 929: f(x)= 0.17259296888837952
# differential_evolution step 930: f(x)= 0.17259296888837952
# differential_evolution step 931: f(x)= 0.17259296888837952
# differential_evolution step 932: f(x)= 0.17259296888837952
# differential_evolution step 933: f(x)= 0.17259296888837952
# differential_evolution step 934: f(x)= 0.17259296888837952
# differential_evolution step 935: f(x)= 0.17259296888837952
# differential_evolution step 936: f(x)= 0.17259296888837952
# differential_evolution step 937: f(x)= 0.17259296888837952
# differential_evolution step 938: f(x)= 0.17259296888837952
# differential_evolution step 939: f(x)= 0.17259296888837952
# differential_evolution step 940: f(x)= 0.17259296888837952
# differential_evolution step 941: f(x)= 0.17259296888837952
# differential_evolution step 942: f(x)= 0.17259296888837952
# differential_evolution step 943: f(x)= 0.17259296888837952
# differential_evolution step 944: f(x)= 0.17259296888837952
# differential_evolution step 945: f(x)= 0.17259296888837952
# differential_evolution step 946: f(x)= 0.17259296888837952
# differential_evolution step 947: f(x)= 0.17259296888837952
# differential_evolution step 948: f(x)= 0.17259296888837952
# differential_evolution step 949: f(x)= 0.1721948937492922
# differential_evolution step 950: f(x)= 0.1721948937492922
# differential_evolution step 951: f(x)= 0.1721948937492922
# differential_evolution step 952: f(x)= 0.1721948937492922
# differential_evolution step 953: f(x)= 0.1721948937492922
# differential_evolution step 954: f(x)= 0.1721948937492922
# differential_evolution step 955: f(x)= 0.17168937625873304
# differential_evolution step 956: f(x)= 0.17168937625873304
# differential_evolution step 957: f(x)= 0.17168937625873304
# differential_evolution step 958: f(x)= 0.17168937625873304
# differential_evolution step 959: f(x)= 0.17168937625873304
# differential_evolution step 960: f(x)= 0.17168937625873304
# differential_evolution step 961: f(x)= 0.17168937625873304
# differential_evolution step 962: f(x)= 0.17168937625873304
# differential_evolution step 963: f(x)= 0.17168937625873304
# differential_evolution step 964: f(x)= 0.17168937625873304
# differential_evolution step 965: f(x)= 0.17168937625873304
# differential_evolution step 966: f(x)= 0.17168937625873304
# differential_evolution step 967: f(x)= 0.17168937625873304
# differential_evolution step 968: f(x)= 0.17168937625873304
# differential_evolution step 969: f(x)= 0.17168937625873304
# differential_evolution step 970: f(x)= 0.17168937625873304
# differential_evolution step 971: f(x)= 0.17168937625873304
# differential_evolution step 972: f(x)= 0.17168937625873304
# differential_evolution step 973: f(x)= 0.17168937625873304
# differential_evolution step 974: f(x)= 0.17168937625873304
# differential_evolution step 975: f(x)= 0.17106212584991726
# differential_evolution step 976: f(x)= 0.17106212584991726
# differential_evolution step 977: f(x)= 0.1707630904371609
# differential_evolution step 978: f(x)= 0.1707630904371609
# differential_evolution step 979: f(x)= 0.1707630904371609
# differential_evolution step 980: f(x)= 0.1707630904371609
# differential_evolution step 981: f(x)= 0.1707630904371609
# differential_evolution step 982: f(x)= 0.1700749908671132
# differential_evolution step 983: f(x)= 0.1700749908671132
# differential_evolution step 984: f(x)= 0.1700749908671132
# differential_evolution step 985: f(x)= 0.1700749908671132
# differential_evolution step 986: f(x)= 0.1700749908671132
# differential_evolution step 987: f(x)= 0.1700749908671132
# differential_evolution step 988: f(x)= 0.1700749908671132
# differential_evolution step 989: f(x)= 0.1700749908671132
# differential_evolution step 990: f(x)= 0.1700749908671132
# differential_evolution step 991: f(x)= 0.1700749908671132
# differential_evolution step 992: f(x)= 0.1700749908671132
# differential_evolution step 993: f(x)= 0.1700749908671132
# differential_evolution step 994: f(x)= 0.1700749908671132
# differential_evolution step 995: f(x)= 0.1700749908671132
# differential_evolution step 996: f(x)= 0.1700749908671132
# differential_evolution step 997: f(x)= 0.1700749908671132
# differential_evolution step 998: f(x)= 0.1700749908671132
# differential_evolution step 999: f(x)= 0.1700749908671132
# differential_evolution step 1000: f(x)= 0.1700749908671132
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution: [5.22542491e-02 1.28730062e+01 2.14661861e+00 5.62139195e+01
#  4.22993468e-01 2.50314503e+00 6.35574231e-01 8.62223022e+01
#  8.33671309e-02 3.96938973e+00 7.03488300e-01 1.40639301e+01
#  6.44488346e+00 5.00515877e-02 5.97700270e-01 3.60839915e+01
#  2.35199730e-01 3.95810407e+01 1.79537191e-01 6.34591275e+01
#  3.51088086e-01 1.11456370e+01 1.00942466e-01 5.77624594e+01]
# Chi quadro minimo: 0.1700749908671132

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\3718685306.py:12: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.4697, r_e=2.1543, n=0.5356, x_0=56.1288
# Sérsic 2: I_e=0.3339, r_e=3.2685, n=0.7935, x_0=86.2450
# Sérsic 3: I_e=0.1775, r_e=3.4941, n=0.2154, x_0=14.2682
# Sérsic 4: I_e=0.0710, r_e=5.2055, n=1.3699, x_0=35.9212
# Sérsic 5: I_e=0.1976, r_e=42.9021, n=0.1676, x_0=65.1833
# Sérsic 6: I_e=0.5244, r_e=10.0085, n=0.1439, x_0=57.6877
# [ 0.16745348  0.37395133  0.28557973  0.09846074  0.07979182  0.53577203
#   0.18561135  0.0807354   0.0284406   0.30726743  0.17508659  0.25921857
#   0.07703392  4.19525623  0.80175969  0.15115601  0.01594422 10.63635441
#   0.09169853 12.23526362  0.03042517  0.50059859  0.02596233  0.20279789]
# 3.981506518191251
# 67.98150651819125 3.981506518191251 114.50559098190546 24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24]) +
        sersic_1d(x_hr, *params[24:28])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (53, 58),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (83, 89),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (13, 18),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (33, 38), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (63, 68),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params7 = result.x

print("Optimize parameters with differential_evolution:", best_params7)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 234511.5953475667
# differential_evolution step 2: f(x)= 234511.5953475667
# differential_evolution step 3: f(x)= 61385.49808866687
# differential_evolution step 4: f(x)= 61385.49808866687
# differential_evolution step 5: f(x)= 61385.49808866687
# differential_evolution step 6: f(x)= 61385.49808866687
# differential_evolution step 7: f(x)= 61385.49808866687
# differential_evolution step 8: f(x)= 61385.49808866687
# differential_evolution step 9: f(x)= 61385.49808866687
# differential_evolution step 10: f(x)= 29066.363478156163
# differential_evolution step 11: f(x)= 25866.41355458248
# differential_evolution step 12: f(x)= 25866.41355458248
# differential_evolution step 13: f(x)= 25866.41355458248
# differential_evolution step 14: f(x)= 25866.41355458248
# differential_evolution step 15: f(x)= 13168.821756589885
# differential_evolution step 16: f(x)= 13168.821756589885
# differential_evolution step 17: f(x)= 13168.821756589885
# differential_evolution step 18: f(x)= 13168.821756589885
# differential_evolution step 19: f(x)= 13168.821756589885
# differential_evolution step 20: f(x)= 11783.848905347546
# differential_evolution step 21: f(x)= 11783.848905347546
# differential_evolution step 22: f(x)= 11783.848905347546
# differential_evolution step 23: f(x)= 11783.848905347546
# differential_evolution step 24: f(x)= 11783.848905347546
# differential_evolution step 25: f(x)= 9302.25434457946
# differential_evolution step 26: f(x)= 4811.135760350849
# differential_evolution step 27: f(x)= 1548.5597722832526
# differential_evolution step 28: f(x)= 1548.5597722832526
# differential_evolution step 29: f(x)= 1548.5597722832526
# differential_evolution step 30: f(x)= 1548.5597722832526
# differential_evolution step 31: f(x)= 1548.5597722832526
# differential_evolution step 32: f(x)= 851.7990619733712
# differential_evolution step 33: f(x)= 851.7990619733712
# differential_evolution step 34: f(x)= 851.7990619733712
# differential_evolution step 35: f(x)= 851.7990619733712
# differential_evolution step 36: f(x)= 851.7990619733712
# differential_evolution step 37: f(x)= 851.7990619733712
# differential_evolution step 38: f(x)= 851.7990619733712
# differential_evolution step 39: f(x)= 851.7990619733712
# differential_evolution step 40: f(x)= 851.7990619733712
# differential_evolution step 41: f(x)= 851.7990619733712
# differential_evolution step 42: f(x)= 851.7990619733712
# differential_evolution step 43: f(x)= 851.7990619733712
# differential_evolution step 44: f(x)= 851.7990619733712
# differential_evolution step 45: f(x)= 851.7990619733712
# differential_evolution step 46: f(x)= 851.7990619733712
# differential_evolution step 47: f(x)= 851.7990619733712
# differential_evolution step 48: f(x)= 452.572033727038
# differential_evolution step 49: f(x)= 452.572033727038
# differential_evolution step 50: f(x)= 452.572033727038
# differential_evolution step 51: f(x)= 452.572033727038
# differential_evolution step 52: f(x)= 452.572033727038
# differential_evolution step 53: f(x)= 347.41826352385294
# differential_evolution step 54: f(x)= 347.41826352385294
# differential_evolution step 55: f(x)= 347.41826352385294
# differential_evolution step 56: f(x)= 347.41826352385294
# differential_evolution step 57: f(x)= 347.41826352385294
# differential_evolution step 58: f(x)= 172.75815638060755
# differential_evolution step 59: f(x)= 172.75815638060755
# differential_evolution step 60: f(x)= 172.75815638060755
# differential_evolution step 61: f(x)= 172.75815638060755
# differential_evolution step 62: f(x)= 172.75815638060755
# differential_evolution step 63: f(x)= 172.75815638060755
# differential_evolution step 64: f(x)= 172.75815638060755
# differential_evolution step 65: f(x)= 172.75815638060755
# differential_evolution step 66: f(x)= 172.75815638060755
# differential_evolution step 67: f(x)= 60.51302131727777
# differential_evolution step 68: f(x)= 60.51302131727777
# differential_evolution step 69: f(x)= 60.51302131727777
# differential_evolution step 70: f(x)= 60.51302131727777
# differential_evolution step 71: f(x)= 60.51302131727777
# differential_evolution step 72: f(x)= 60.51302131727777
# differential_evolution step 73: f(x)= 60.51302131727777
# differential_evolution step 74: f(x)= 60.51302131727777
# differential_evolution step 75: f(x)= 60.51302131727777
# differential_evolution step 76: f(x)= 60.51302131727777
# differential_evolution step 77: f(x)= 60.51302131727777
# differential_evolution step 78: f(x)= 60.51302131727777
# differential_evolution step 79: f(x)= 60.51302131727777
# differential_evolution step 80: f(x)= 60.51302131727777
# differential_evolution step 81: f(x)= 60.51302131727777
# differential_evolution step 82: f(x)= 60.51302131727777
# differential_evolution step 83: f(x)= 60.51302131727777
# differential_evolution step 84: f(x)= 60.51302131727777
# differential_evolution step 85: f(x)= 60.51302131727777
# differential_evolution step 86: f(x)= 60.51302131727777
# differential_evolution step 87: f(x)= 60.51302131727777
# differential_evolution step 88: f(x)= 60.51302131727777
# differential_evolution step 89: f(x)= 60.51302131727777
# differential_evolution step 90: f(x)= 60.51302131727777
# differential_evolution step 91: f(x)= 60.51302131727777
# differential_evolution step 92: f(x)= 60.51302131727777
# differential_evolution step 93: f(x)= 60.51302131727777
# differential_evolution step 94: f(x)= 60.51302131727777
# differential_evolution step 95: f(x)= 60.51302131727777
# differential_evolution step 96: f(x)= 60.51302131727777
# differential_evolution step 97: f(x)= 60.51302131727777
# differential_evolution step 98: f(x)= 60.51302131727777
# differential_evolution step 99: f(x)= 60.51302131727777
# differential_evolution step 100: f(x)= 60.51302131727777
# differential_evolution step 101: f(x)= 60.51302131727777
# differential_evolution step 102: f(x)= 60.51302131727777
# differential_evolution step 103: f(x)= 60.51302131727777
# differential_evolution step 104: f(x)= 60.51302131727777
# differential_evolution step 105: f(x)= 60.51302131727777
# differential_evolution step 106: f(x)= 60.51302131727777
# differential_evolution step 107: f(x)= 60.51302131727777
# differential_evolution step 108: f(x)= 60.51302131727777
# differential_evolution step 109: f(x)= 60.51302131727777
# differential_evolution step 110: f(x)= 60.51302131727777
# differential_evolution step 111: f(x)= 60.51302131727777
# differential_evolution step 112: f(x)= 60.51302131727777
# differential_evolution step 113: f(x)= 60.51302131727777
# differential_evolution step 114: f(x)= 60.51302131727777
# differential_evolution step 115: f(x)= 60.51302131727777
# differential_evolution step 116: f(x)= 60.51302131727777
# differential_evolution step 117: f(x)= 60.51302131727777
# differential_evolution step 118: f(x)= 60.51302131727777
# differential_evolution step 119: f(x)= 60.51302131727777
# differential_evolution step 120: f(x)= 40.301782205943795
# differential_evolution step 121: f(x)= 40.301782205943795
# differential_evolution step 122: f(x)= 40.301782205943795
# differential_evolution step 123: f(x)= 40.301782205943795
# differential_evolution step 124: f(x)= 40.301782205943795
# differential_evolution step 125: f(x)= 40.301782205943795
# differential_evolution step 126: f(x)= 40.301782205943795
# differential_evolution step 127: f(x)= 40.301782205943795
# differential_evolution step 128: f(x)= 40.301782205943795
# differential_evolution step 129: f(x)= 40.301782205943795
# differential_evolution step 130: f(x)= 40.301782205943795
# differential_evolution step 131: f(x)= 40.301782205943795
# differential_evolution step 132: f(x)= 40.301782205943795
# differential_evolution step 133: f(x)= 40.301782205943795
# differential_evolution step 134: f(x)= 40.301782205943795
# differential_evolution step 135: f(x)= 40.301782205943795
# differential_evolution step 136: f(x)= 40.301782205943795
# differential_evolution step 137: f(x)= 40.301782205943795
# differential_evolution step 138: f(x)= 40.301782205943795
# differential_evolution step 139: f(x)= 40.301782205943795
# differential_evolution step 140: f(x)= 40.301782205943795
# differential_evolution step 141: f(x)= 40.301782205943795
# differential_evolution step 142: f(x)= 40.301782205943795
# differential_evolution step 143: f(x)= 10.699135437205827
# differential_evolution step 144: f(x)= 10.699135437205827
# differential_evolution step 145: f(x)= 10.699135437205827
# differential_evolution step 146: f(x)= 10.699135437205827
# differential_evolution step 147: f(x)= 10.699135437205827
# differential_evolution step 148: f(x)= 10.699135437205827
# differential_evolution step 149: f(x)= 10.699135437205827
# differential_evolution step 150: f(x)= 10.699135437205827
# differential_evolution step 151: f(x)= 10.699135437205827
# differential_evolution step 152: f(x)= 10.699135437205827
# differential_evolution step 153: f(x)= 10.699135437205827
# differential_evolution step 154: f(x)= 10.699135437205827
# differential_evolution step 155: f(x)= 10.699135437205827
# differential_evolution step 156: f(x)= 10.699135437205827
# differential_evolution step 157: f(x)= 10.699135437205827
# differential_evolution step 158: f(x)= 10.699135437205827
# differential_evolution step 159: f(x)= 10.699135437205827
# differential_evolution step 160: f(x)= 10.699135437205827
# differential_evolution step 161: f(x)= 10.699135437205827
# differential_evolution step 162: f(x)= 10.699135437205827
# differential_evolution step 163: f(x)= 10.699135437205827
# differential_evolution step 164: f(x)= 10.699135437205827
# differential_evolution step 165: f(x)= 10.699135437205827
# differential_evolution step 166: f(x)= 10.699135437205827
# differential_evolution step 167: f(x)= 10.699135437205827
# differential_evolution step 168: f(x)= 10.699135437205827
# differential_evolution step 169: f(x)= 10.699135437205827
# differential_evolution step 170: f(x)= 10.699135437205827
# differential_evolution step 171: f(x)= 10.699135437205827
# differential_evolution step 172: f(x)= 10.699135437205827
# differential_evolution step 173: f(x)= 10.699135437205827
# differential_evolution step 174: f(x)= 10.699135437205827
# differential_evolution step 175: f(x)= 10.699135437205827
# differential_evolution step 176: f(x)= 10.699135437205827
# differential_evolution step 177: f(x)= 10.699135437205827
# differential_evolution step 178: f(x)= 10.699135437205827
# differential_evolution step 179: f(x)= 10.699135437205827
# differential_evolution step 180: f(x)= 10.699135437205827
# differential_evolution step 181: f(x)= 10.699135437205827
# differential_evolution step 182: f(x)= 9.701873577190046
# differential_evolution step 183: f(x)= 6.01370031745713
# differential_evolution step 184: f(x)= 6.01370031745713
# differential_evolution step 185: f(x)= 6.01370031745713
# differential_evolution step 186: f(x)= 6.01370031745713
# differential_evolution step 187: f(x)= 6.01370031745713
# differential_evolution step 188: f(x)= 6.01370031745713
# differential_evolution step 189: f(x)= 6.01370031745713
# differential_evolution step 190: f(x)= 6.01370031745713
# differential_evolution step 191: f(x)= 6.01370031745713
# differential_evolution step 192: f(x)= 6.01370031745713
# differential_evolution step 193: f(x)= 6.01370031745713
# differential_evolution step 194: f(x)= 6.01370031745713
# differential_evolution step 195: f(x)= 6.01370031745713
# differential_evolution step 196: f(x)= 6.01370031745713
# differential_evolution step 197: f(x)= 5.913868373570666
# differential_evolution step 198: f(x)= 5.913868373570666
# differential_evolution step 199: f(x)= 5.913868373570666
# differential_evolution step 200: f(x)= 5.913868373570666
# differential_evolution step 201: f(x)= 5.913868373570666
# differential_evolution step 202: f(x)= 5.913868373570666
# differential_evolution step 203: f(x)= 5.913868373570666
# differential_evolution step 204: f(x)= 5.913868373570666
# differential_evolution step 205: f(x)= 5.913868373570666
# differential_evolution step 206: f(x)= 5.913868373570666
# differential_evolution step 207: f(x)= 5.913868373570666
# differential_evolution step 208: f(x)= 5.913868373570666
# differential_evolution step 209: f(x)= 5.913868373570666
# differential_evolution step 210: f(x)= 5.913868373570666
# differential_evolution step 211: f(x)= 5.913868373570666
# differential_evolution step 212: f(x)= 5.913868373570666
# differential_evolution step 213: f(x)= 5.913868373570666
# differential_evolution step 214: f(x)= 5.913868373570666
# differential_evolution step 215: f(x)= 5.913868373570666
# differential_evolution step 216: f(x)= 5.913868373570666
# differential_evolution step 217: f(x)= 5.913868373570666
# differential_evolution step 218: f(x)= 5.913868373570666
# differential_evolution step 219: f(x)= 5.913868373570666
# differential_evolution step 220: f(x)= 5.337420206616007
# differential_evolution step 221: f(x)= 5.337420206616007
# differential_evolution step 222: f(x)= 4.5717547703136345
# differential_evolution step 223: f(x)= 4.5717547703136345
# differential_evolution step 224: f(x)= 4.5717547703136345
# differential_evolution step 225: f(x)= 4.5717547703136345
# differential_evolution step 226: f(x)= 4.5717547703136345
# differential_evolution step 227: f(x)= 4.5717547703136345
# differential_evolution step 228: f(x)= 4.5717547703136345
# differential_evolution step 229: f(x)= 4.5717547703136345
# differential_evolution step 230: f(x)= 4.5717547703136345
# differential_evolution step 231: f(x)= 4.5717547703136345
# differential_evolution step 232: f(x)= 4.5717547703136345
# differential_evolution step 233: f(x)= 4.5717547703136345
# differential_evolution step 234: f(x)= 4.5717547703136345
# differential_evolution step 235: f(x)= 4.5717547703136345
# differential_evolution step 236: f(x)= 4.5717547703136345
# differential_evolution step 237: f(x)= 4.5717547703136345
# differential_evolution step 238: f(x)= 4.5717547703136345
# differential_evolution step 239: f(x)= 4.5717547703136345
# differential_evolution step 240: f(x)= 4.5717547703136345
# differential_evolution step 241: f(x)= 4.5717547703136345
# differential_evolution step 242: f(x)= 4.5717547703136345
# differential_evolution step 243: f(x)= 4.5717547703136345
# differential_evolution step 244: f(x)= 4.5717547703136345
# differential_evolution step 245: f(x)= 4.5717547703136345
# differential_evolution step 246: f(x)= 4.5717547703136345
# differential_evolution step 247: f(x)= 4.5717547703136345
# differential_evolution step 248: f(x)= 4.5717547703136345
# differential_evolution step 249: f(x)= 4.5717547703136345
# differential_evolution step 250: f(x)= 4.5717547703136345
# differential_evolution step 251: f(x)= 4.5717547703136345
# differential_evolution step 252: f(x)= 4.5717547703136345
# differential_evolution step 253: f(x)= 4.5717547703136345
# differential_evolution step 254: f(x)= 4.5717547703136345
# differential_evolution step 255: f(x)= 4.5717547703136345
# differential_evolution step 256: f(x)= 4.5717547703136345
# differential_evolution step 257: f(x)= 4.5717547703136345
# differential_evolution step 258: f(x)= 4.214282590494007
# differential_evolution step 259: f(x)= 4.214282590494007
# differential_evolution step 260: f(x)= 4.214282590494007
# differential_evolution step 261: f(x)= 4.214282590494007
# differential_evolution step 262: f(x)= 4.214282590494007
# differential_evolution step 263: f(x)= 4.214282590494007
# differential_evolution step 264: f(x)= 4.214282590494007
# differential_evolution step 265: f(x)= 3.8005157760473867
# differential_evolution step 266: f(x)= 3.8005157760473867
# differential_evolution step 267: f(x)= 3.8005157760473867
# differential_evolution step 268: f(x)= 3.8005157760473867
# differential_evolution step 269: f(x)= 3.8005157760473867
# differential_evolution step 270: f(x)= 3.8005157760473867
# differential_evolution step 271: f(x)= 3.8005157760473867
# differential_evolution step 272: f(x)= 2.6016330373265197
# differential_evolution step 273: f(x)= 2.6016330373265197
# differential_evolution step 274: f(x)= 2.6016330373265197
# differential_evolution step 275: f(x)= 2.6016330373265197
# differential_evolution step 276: f(x)= 2.6016330373265197
# differential_evolution step 277: f(x)= 2.6016330373265197
# differential_evolution step 278: f(x)= 2.6016330373265197
# differential_evolution step 279: f(x)= 2.6016330373265197
# differential_evolution step 280: f(x)= 2.6016330373265197
# differential_evolution step 281: f(x)= 2.6016330373265197
# differential_evolution step 282: f(x)= 2.6016330373265197
# differential_evolution step 283: f(x)= 2.6016330373265197
# differential_evolution step 284: f(x)= 2.6016330373265197
# differential_evolution step 285: f(x)= 2.6016330373265197
# differential_evolution step 286: f(x)= 2.6016330373265197
# differential_evolution step 287: f(x)= 2.6016330373265197
# differential_evolution step 288: f(x)= 2.6016330373265197
# differential_evolution step 289: f(x)= 2.6016330373265197
# differential_evolution step 290: f(x)= 2.6016330373265197
# differential_evolution step 291: f(x)= 2.6016330373265197
# differential_evolution step 292: f(x)= 2.6016330373265197
# differential_evolution step 293: f(x)= 2.6016330373265197
# differential_evolution step 294: f(x)= 2.6016330373265197
# differential_evolution step 295: f(x)= 2.0587228340763417
# differential_evolution step 296: f(x)= 2.0587228340763417
# differential_evolution step 297: f(x)= 2.0587228340763417
# differential_evolution step 298: f(x)= 2.0587228340763417
# differential_evolution step 299: f(x)= 2.0587228340763417
# differential_evolution step 300: f(x)= 2.0587228340763417
# differential_evolution step 301: f(x)= 2.0587228340763417
# differential_evolution step 302: f(x)= 2.0587228340763417
# differential_evolution step 303: f(x)= 2.0587228340763417
# differential_evolution step 304: f(x)= 2.0587228340763417
# differential_evolution step 305: f(x)= 2.0587228340763417
# differential_evolution step 306: f(x)= 2.0587228340763417
# differential_evolution step 307: f(x)= 2.0587228340763417
# differential_evolution step 308: f(x)= 2.0587228340763417
# differential_evolution step 309: f(x)= 2.0587228340763417
# differential_evolution step 310: f(x)= 2.0587228340763417
# differential_evolution step 311: f(x)= 2.0587228340763417
# differential_evolution step 312: f(x)= 2.0587228340763417
# differential_evolution step 313: f(x)= 2.0587228340763417
# differential_evolution step 314: f(x)= 2.0587228340763417
# differential_evolution step 315: f(x)= 2.0587228340763417
# differential_evolution step 316: f(x)= 2.0587228340763417
# differential_evolution step 317: f(x)= 2.0587228340763417
# differential_evolution step 318: f(x)= 2.0587228340763417
# differential_evolution step 319: f(x)= 2.0587228340763417
# differential_evolution step 320: f(x)= 2.0587228340763417
# differential_evolution step 321: f(x)= 2.0587228340763417
# differential_evolution step 322: f(x)= 2.0587228340763417
# differential_evolution step 323: f(x)= 2.0587228340763417
# differential_evolution step 324: f(x)= 2.0587228340763417
# differential_evolution step 325: f(x)= 2.0587228340763417
# differential_evolution step 326: f(x)= 2.0587228340763417
# differential_evolution step 327: f(x)= 2.0587228340763417
# differential_evolution step 328: f(x)= 2.0587228340763417
# differential_evolution step 329: f(x)= 2.0587228340763417
# differential_evolution step 330: f(x)= 2.0587228340763417
# differential_evolution step 331: f(x)= 2.0587228340763417
# differential_evolution step 332: f(x)= 2.0587228340763417
# differential_evolution step 333: f(x)= 2.0587228340763417
# differential_evolution step 334: f(x)= 2.0587228340763417
# differential_evolution step 335: f(x)= 2.0587228340763417
# differential_evolution step 336: f(x)= 2.0587228340763417
# differential_evolution step 337: f(x)= 2.0587228340763417
# differential_evolution step 338: f(x)= 2.0587228340763417
# differential_evolution step 339: f(x)= 2.0587228340763417
# differential_evolution step 340: f(x)= 2.0587228340763417
# differential_evolution step 341: f(x)= 2.0587228340763417
# differential_evolution step 342: f(x)= 2.0587228340763417
# differential_evolution step 343: f(x)= 2.0587228340763417
# differential_evolution step 344: f(x)= 2.0587228340763417
# differential_evolution step 345: f(x)= 2.0587228340763417
# differential_evolution step 346: f(x)= 2.0587228340763417
# differential_evolution step 347: f(x)= 2.0587228340763417
# differential_evolution step 348: f(x)= 2.0587228340763417
# differential_evolution step 349: f(x)= 2.0587228340763417
# differential_evolution step 350: f(x)= 2.0587228340763417
# differential_evolution step 351: f(x)= 2.0587228340763417
# differential_evolution step 352: f(x)= 2.0587228340763417
# differential_evolution step 353: f(x)= 1.448155256634481
# differential_evolution step 354: f(x)= 1.448155256634481
# differential_evolution step 355: f(x)= 1.448155256634481
# differential_evolution step 356: f(x)= 1.448155256634481
# differential_evolution step 357: f(x)= 1.448155256634481
# differential_evolution step 358: f(x)= 1.448155256634481
# differential_evolution step 359: f(x)= 1.448155256634481
# differential_evolution step 360: f(x)= 1.448155256634481
# differential_evolution step 361: f(x)= 1.448155256634481
# differential_evolution step 362: f(x)= 1.448155256634481
# differential_evolution step 363: f(x)= 1.448155256634481
# differential_evolution step 364: f(x)= 1.448155256634481
# differential_evolution step 365: f(x)= 1.448155256634481
# differential_evolution step 366: f(x)= 1.448155256634481
# differential_evolution step 367: f(x)= 1.448155256634481
# differential_evolution step 368: f(x)= 1.448155256634481
# differential_evolution step 369: f(x)= 1.448155256634481
# differential_evolution step 370: f(x)= 1.448155256634481
# differential_evolution step 371: f(x)= 1.448155256634481
# differential_evolution step 372: f(x)= 1.448155256634481
# differential_evolution step 373: f(x)= 1.448155256634481
# differential_evolution step 374: f(x)= 1.448155256634481
# differential_evolution step 375: f(x)= 1.448155256634481
# differential_evolution step 376: f(x)= 1.448155256634481
# differential_evolution step 377: f(x)= 1.448155256634481
# differential_evolution step 378: f(x)= 1.448155256634481
# differential_evolution step 379: f(x)= 1.448155256634481
# differential_evolution step 380: f(x)= 1.448155256634481
# differential_evolution step 381: f(x)= 1.4133550910144703
# differential_evolution step 382: f(x)= 1.4133550910144703
# differential_evolution step 383: f(x)= 1.4133550910144703
# differential_evolution step 384: f(x)= 1.4133550910144703
# differential_evolution step 385: f(x)= 1.2070524748277003
# differential_evolution step 386: f(x)= 1.2070524748277003
# differential_evolution step 387: f(x)= 1.2070524748277003
# differential_evolution step 388: f(x)= 1.2070524748277003
# differential_evolution step 389: f(x)= 1.2070524748277003
# differential_evolution step 390: f(x)= 1.2070524748277003
# differential_evolution step 391: f(x)= 1.2070524748277003
# differential_evolution step 392: f(x)= 1.2070524748277003
# differential_evolution step 393: f(x)= 1.2070524748277003
# differential_evolution step 394: f(x)= 1.2070524748277003
# differential_evolution step 395: f(x)= 1.2070524748277003
# differential_evolution step 396: f(x)= 1.2070524748277003
# differential_evolution step 397: f(x)= 1.2070524748277003
# differential_evolution step 398: f(x)= 1.2070524748277003
# differential_evolution step 399: f(x)= 1.2070524748277003
# differential_evolution step 400: f(x)= 1.2070524748277003
# differential_evolution step 401: f(x)= 1.2070524748277003
# differential_evolution step 402: f(x)= 1.2070524748277003
# differential_evolution step 403: f(x)= 1.2070524748277003
# differential_evolution step 404: f(x)= 1.2070524748277003
# differential_evolution step 405: f(x)= 1.2070524748277003
# differential_evolution step 406: f(x)= 1.2070524748277003
# differential_evolution step 407: f(x)= 1.2070524748277003
# differential_evolution step 408: f(x)= 1.2070524748277003
# differential_evolution step 409: f(x)= 1.2070524748277003
# differential_evolution step 410: f(x)= 1.2070524748277003
# differential_evolution step 411: f(x)= 1.2070524748277003
# differential_evolution step 412: f(x)= 1.2070524748277003
# differential_evolution step 413: f(x)= 1.2070524748277003
# differential_evolution step 414: f(x)= 1.2070524748277003
# differential_evolution step 415: f(x)= 1.2070524748277003
# differential_evolution step 416: f(x)= 1.2070524748277003
# differential_evolution step 417: f(x)= 1.2070524748277003
# differential_evolution step 418: f(x)= 1.2070524748277003
# differential_evolution step 419: f(x)= 1.2070524748277003
# differential_evolution step 420: f(x)= 1.2070524748277003
# differential_evolution step 421: f(x)= 1.2070524748277003
# differential_evolution step 422: f(x)= 1.2070524748277003
# differential_evolution step 423: f(x)= 1.2070524748277003
# differential_evolution step 424: f(x)= 1.2070524748277003
# differential_evolution step 425: f(x)= 1.2070524748277003
# differential_evolution step 426: f(x)= 1.2070524748277003
# differential_evolution step 427: f(x)= 1.2070524748277003
# differential_evolution step 428: f(x)= 1.2070524748277003
# differential_evolution step 429: f(x)= 1.2070524748277003
# differential_evolution step 430: f(x)= 1.2070524748277003
# differential_evolution step 431: f(x)= 1.2070524748277003
# differential_evolution step 432: f(x)= 1.2070524748277003
# differential_evolution step 433: f(x)= 1.2070524748277003
# differential_evolution step 434: f(x)= 1.2070524748277003
# differential_evolution step 435: f(x)= 1.2070524748277003
# differential_evolution step 436: f(x)= 1.2070524748277003
# differential_evolution step 437: f(x)= 1.1956994638276708
# differential_evolution step 438: f(x)= 1.1956994638276708
# differential_evolution step 439: f(x)= 1.1956994638276708
# differential_evolution step 440: f(x)= 1.1956994638276708
# differential_evolution step 441: f(x)= 1.1956994638276708
# differential_evolution step 442: f(x)= 1.1956994638276708
# differential_evolution step 443: f(x)= 1.1956994638276708
# differential_evolution step 444: f(x)= 1.1956994638276708
# differential_evolution step 445: f(x)= 1.1956994638276708
# differential_evolution step 446: f(x)= 1.1956994638276708
# differential_evolution step 447: f(x)= 1.1956994638276708
# differential_evolution step 448: f(x)= 1.1956994638276708
# differential_evolution step 449: f(x)= 1.1956994638276708
# differential_evolution step 450: f(x)= 1.0156389457044075
# differential_evolution step 451: f(x)= 1.0156389457044075
# differential_evolution step 452: f(x)= 1.0156389457044075
# differential_evolution step 453: f(x)= 0.977329249531777
# differential_evolution step 454: f(x)= 0.977329249531777
# differential_evolution step 455: f(x)= 0.977329249531777
# differential_evolution step 456: f(x)= 0.977329249531777
# differential_evolution step 457: f(x)= 0.977329249531777
# differential_evolution step 458: f(x)= 0.977329249531777
# differential_evolution step 459: f(x)= 0.977329249531777
# differential_evolution step 460: f(x)= 0.977329249531777
# differential_evolution step 461: f(x)= 0.977329249531777
# differential_evolution step 462: f(x)= 0.977329249531777
# differential_evolution step 463: f(x)= 0.977329249531777
# differential_evolution step 464: f(x)= 0.977329249531777
# differential_evolution step 465: f(x)= 0.977329249531777
# differential_evolution step 466: f(x)= 0.977329249531777
# differential_evolution step 467: f(x)= 0.977329249531777
# differential_evolution step 468: f(x)= 0.977329249531777
# differential_evolution step 469: f(x)= 0.977329249531777
# differential_evolution step 470: f(x)= 0.977329249531777
# differential_evolution step 471: f(x)= 0.977329249531777
# differential_evolution step 472: f(x)= 0.977329249531777
# differential_evolution step 473: f(x)= 0.977329249531777
# differential_evolution step 474: f(x)= 0.977329249531777
# differential_evolution step 475: f(x)= 0.977329249531777
# differential_evolution step 476: f(x)= 0.977329249531777
# differential_evolution step 477: f(x)= 0.977329249531777
# differential_evolution step 478: f(x)= 0.977329249531777
# differential_evolution step 479: f(x)= 0.977329249531777
# differential_evolution step 480: f(x)= 0.977329249531777
# differential_evolution step 481: f(x)= 0.977329249531777
# differential_evolution step 482: f(x)= 0.977329249531777
# differential_evolution step 483: f(x)= 0.977329249531777
# differential_evolution step 484: f(x)= 0.977329249531777
# differential_evolution step 485: f(x)= 0.977329249531777
# differential_evolution step 486: f(x)= 0.977329249531777
# differential_evolution step 487: f(x)= 0.977329249531777
# differential_evolution step 488: f(x)= 0.977329249531777
# differential_evolution step 489: f(x)= 0.7676141748141455
# differential_evolution step 490: f(x)= 0.7676141748141455
# differential_evolution step 491: f(x)= 0.7676141748141455
# differential_evolution step 492: f(x)= 0.7676141748141455
# differential_evolution step 493: f(x)= 0.7676141748141455
# differential_evolution step 494: f(x)= 0.7676141748141455
# differential_evolution step 495: f(x)= 0.7676141748141455
# differential_evolution step 496: f(x)= 0.7676141748141455
# differential_evolution step 497: f(x)= 0.7676141748141455
# differential_evolution step 498: f(x)= 0.7676141748141455
# differential_evolution step 499: f(x)= 0.7676141748141455
# differential_evolution step 500: f(x)= 0.7676141748141455
# differential_evolution step 501: f(x)= 0.7676141748141455
# differential_evolution step 502: f(x)= 0.7676141748141455
# differential_evolution step 503: f(x)= 0.7676141748141455
# differential_evolution step 504: f(x)= 0.7676141748141455
# differential_evolution step 505: f(x)= 0.7676141748141455
# differential_evolution step 506: f(x)= 0.7676141748141455
# differential_evolution step 507: f(x)= 0.7676141748141455
# differential_evolution step 508: f(x)= 0.7676141748141455
# differential_evolution step 509: f(x)= 0.7676141748141455
# differential_evolution step 510: f(x)= 0.7676141748141455
# differential_evolution step 511: f(x)= 0.7676141748141455
# differential_evolution step 512: f(x)= 0.7676141748141455
# differential_evolution step 513: f(x)= 0.7676141748141455
# differential_evolution step 514: f(x)= 0.7676141748141455
# differential_evolution step 515: f(x)= 0.7676141748141455
# differential_evolution step 516: f(x)= 0.7676141748141455
# differential_evolution step 517: f(x)= 0.7676141748141455
# differential_evolution step 518: f(x)= 0.7676141748141455
# differential_evolution step 519: f(x)= 0.7676141748141455
# differential_evolution step 520: f(x)= 0.7676141748141455
# differential_evolution step 521: f(x)= 0.7676141748141455
# differential_evolution step 522: f(x)= 0.7676141748141455
# differential_evolution step 523: f(x)= 0.7676141748141455
# differential_evolution step 524: f(x)= 0.7676141748141455
# differential_evolution step 525: f(x)= 0.7676141748141455
# differential_evolution step 526: f(x)= 0.7676141748141455
# differential_evolution step 527: f(x)= 0.7676141748141455
# differential_evolution step 528: f(x)= 0.7676141748141455
# differential_evolution step 529: f(x)= 0.7676141748141455
# differential_evolution step 530: f(x)= 0.7676141748141455
# differential_evolution step 531: f(x)= 0.7676141748141455
# differential_evolution step 532: f(x)= 0.7676141748141455
# differential_evolution step 533: f(x)= 0.7676141748141455
# differential_evolution step 534: f(x)= 0.7676141748141455
# differential_evolution step 535: f(x)= 0.7676141748141455
# differential_evolution step 536: f(x)= 0.7676141748141455
# differential_evolution step 537: f(x)= 0.7676141748141455
# differential_evolution step 538: f(x)= 0.7676141748141455
# differential_evolution step 539: f(x)= 0.7676141748141455
# differential_evolution step 540: f(x)= 0.7676141748141455
# differential_evolution step 541: f(x)= 0.7676141748141455
# differential_evolution step 542: f(x)= 0.7676141748141455
# differential_evolution step 543: f(x)= 0.7676141748141455
# differential_evolution step 544: f(x)= 0.7676141748141455
# differential_evolution step 545: f(x)= 0.7676141748141455
# differential_evolution step 546: f(x)= 0.7676141748141455
# differential_evolution step 547: f(x)= 0.7676141748141455
# differential_evolution step 548: f(x)= 0.7676141748141455
# differential_evolution step 549: f(x)= 0.7676141748141455
# differential_evolution step 550: f(x)= 0.7676141748141455
# differential_evolution step 551: f(x)= 0.7676141748141455
# differential_evolution step 552: f(x)= 0.7292145102500758
# differential_evolution step 553: f(x)= 0.6143502190263895
# differential_evolution step 554: f(x)= 0.6143502190263895
# differential_evolution step 555: f(x)= 0.6143502190263895
# differential_evolution step 556: f(x)= 0.6143502190263895
# differential_evolution step 557: f(x)= 0.6143502190263895
# differential_evolution step 558: f(x)= 0.6143502190263895
# differential_evolution step 559: f(x)= 0.6143502190263895
# differential_evolution step 560: f(x)= 0.6143502190263895
# differential_evolution step 561: f(x)= 0.6143502190263895
# differential_evolution step 562: f(x)= 0.6143502190263895
# differential_evolution step 563: f(x)= 0.6143502190263895
# differential_evolution step 564: f(x)= 0.6143502190263895
# differential_evolution step 565: f(x)= 0.6143502190263895
# differential_evolution step 566: f(x)= 0.6143502190263895
# differential_evolution step 567: f(x)= 0.6143502190263895
# differential_evolution step 568: f(x)= 0.6143502190263895
# differential_evolution step 569: f(x)= 0.6143502190263895
# differential_evolution step 570: f(x)= 0.6143502190263895
# differential_evolution step 571: f(x)= 0.6143502190263895
# differential_evolution step 572: f(x)= 0.5948850333967136
# differential_evolution step 573: f(x)= 0.5948850333967136
# differential_evolution step 574: f(x)= 0.5948850333967136
# differential_evolution step 575: f(x)= 0.5948850333967136
# differential_evolution step 576: f(x)= 0.5948850333967136
# differential_evolution step 577: f(x)= 0.5783309328152042
# differential_evolution step 578: f(x)= 0.5783309328152042
# differential_evolution step 579: f(x)= 0.5783235934108872
# differential_evolution step 580: f(x)= 0.5783235934108872
# differential_evolution step 581: f(x)= 0.5783235934108872
# differential_evolution step 582: f(x)= 0.5783235934108872
# differential_evolution step 583: f(x)= 0.5783235934108872
# differential_evolution step 584: f(x)= 0.5783235934108872
# differential_evolution step 585: f(x)= 0.5783235934108872
# differential_evolution step 586: f(x)= 0.5783235934108872
# differential_evolution step 587: f(x)= 0.5783235934108872
# differential_evolution step 588: f(x)= 0.5783235934108872
# differential_evolution step 589: f(x)= 0.5783235934108872
# differential_evolution step 590: f(x)= 0.5659879614619321
# differential_evolution step 591: f(x)= 0.5659879614619321
# differential_evolution step 592: f(x)= 0.5659879614619321
# differential_evolution step 593: f(x)= 0.5659879614619321
# differential_evolution step 594: f(x)= 0.5659879614619321
# differential_evolution step 595: f(x)= 0.5659879614619321
# differential_evolution step 596: f(x)= 0.5659879614619321
# differential_evolution step 597: f(x)= 0.5659879614619321
# differential_evolution step 598: f(x)= 0.5659879614619321
# differential_evolution step 599: f(x)= 0.5595651441072623
# differential_evolution step 600: f(x)= 0.5595651441072623
# differential_evolution step 601: f(x)= 0.5595651441072623
# differential_evolution step 602: f(x)= 0.5595651441072623
# differential_evolution step 603: f(x)= 0.5595651441072623
# differential_evolution step 604: f(x)= 0.503502945072829
# differential_evolution step 605: f(x)= 0.503502945072829
# differential_evolution step 606: f(x)= 0.503502945072829
# differential_evolution step 607: f(x)= 0.503502945072829
# differential_evolution step 608: f(x)= 0.503502945072829
# differential_evolution step 609: f(x)= 0.503502945072829
# differential_evolution step 610: f(x)= 0.503502945072829
# differential_evolution step 611: f(x)= 0.503502945072829
# differential_evolution step 612: f(x)= 0.503502945072829
# differential_evolution step 613: f(x)= 0.503502945072829
# differential_evolution step 614: f(x)= 0.503502945072829
# differential_evolution step 615: f(x)= 0.503502945072829
# differential_evolution step 616: f(x)= 0.503502945072829
# differential_evolution step 617: f(x)= 0.503502945072829
# differential_evolution step 618: f(x)= 0.503502945072829
# differential_evolution step 619: f(x)= 0.503502945072829
# differential_evolution step 620: f(x)= 0.49603886216159576
# differential_evolution step 621: f(x)= 0.49603886216159576
# differential_evolution step 622: f(x)= 0.49603886216159576
# differential_evolution step 623: f(x)= 0.49603886216159576
# differential_evolution step 624: f(x)= 0.49603886216159576
# differential_evolution step 625: f(x)= 0.49603886216159576
# differential_evolution step 626: f(x)= 0.49603886216159576
# differential_evolution step 627: f(x)= 0.49603886216159576
# differential_evolution step 628: f(x)= 0.4643696308917052
# differential_evolution step 629: f(x)= 0.4643696308917052
# differential_evolution step 630: f(x)= 0.4643696308917052
# differential_evolution step 631: f(x)= 0.4643696308917052
# differential_evolution step 632: f(x)= 0.4643696308917052
# differential_evolution step 633: f(x)= 0.4643696308917052
# differential_evolution step 634: f(x)= 0.4643696308917052
# differential_evolution step 635: f(x)= 0.4643696308917052
# differential_evolution step 636: f(x)= 0.462633430203181
# differential_evolution step 637: f(x)= 0.462633430203181
# differential_evolution step 638: f(x)= 0.462633430203181
# differential_evolution step 639: f(x)= 0.462633430203181
# differential_evolution step 640: f(x)= 0.462633430203181
# differential_evolution step 641: f(x)= 0.4378639044114032
# differential_evolution step 642: f(x)= 0.4378639044114032
# differential_evolution step 643: f(x)= 0.4378639044114032
# differential_evolution step 644: f(x)= 0.4016336272685583
# differential_evolution step 645: f(x)= 0.4016336272685583
# differential_evolution step 646: f(x)= 0.4016336272685583
# differential_evolution step 647: f(x)= 0.4016336272685583
# differential_evolution step 648: f(x)= 0.4016336272685583
# differential_evolution step 649: f(x)= 0.4016336272685583
# differential_evolution step 650: f(x)= 0.4016336272685583
# differential_evolution step 651: f(x)= 0.4016336272685583
# differential_evolution step 652: f(x)= 0.4016336272685583
# differential_evolution step 653: f(x)= 0.4016336272685583
# differential_evolution step 654: f(x)= 0.4016336272685583
# differential_evolution step 655: f(x)= 0.4016336272685583
# differential_evolution step 656: f(x)= 0.4016336272685583
# differential_evolution step 657: f(x)= 0.4016336272685583
# differential_evolution step 658: f(x)= 0.4016336272685583
# differential_evolution step 659: f(x)= 0.4016336272685583
# differential_evolution step 660: f(x)= 0.4016336272685583
# differential_evolution step 661: f(x)= 0.4016336272685583
# differential_evolution step 662: f(x)= 0.4016336272685583
# differential_evolution step 663: f(x)= 0.4016336272685583
# differential_evolution step 664: f(x)= 0.4016336272685583
# differential_evolution step 665: f(x)= 0.4016336272685583
# differential_evolution step 666: f(x)= 0.4016336272685583
# differential_evolution step 667: f(x)= 0.4016336272685583
# differential_evolution step 668: f(x)= 0.4016336272685583
# differential_evolution step 669: f(x)= 0.4016336272685583
# differential_evolution step 670: f(x)= 0.4016336272685583
# differential_evolution step 671: f(x)= 0.4016336272685583
# differential_evolution step 672: f(x)= 0.4016336272685583
# differential_evolution step 673: f(x)= 0.4016336272685583
# differential_evolution step 674: f(x)= 0.4016336272685583
# differential_evolution step 675: f(x)= 0.4016336272685583
# differential_evolution step 676: f(x)= 0.4016336272685583
# differential_evolution step 677: f(x)= 0.4016336272685583
# differential_evolution step 678: f(x)= 0.37123848110882696
# differential_evolution step 679: f(x)= 0.37123848110882696
# differential_evolution step 680: f(x)= 0.37123848110882696
# differential_evolution step 681: f(x)= 0.37123848110882696
# differential_evolution step 682: f(x)= 0.37123848110882696
# differential_evolution step 683: f(x)= 0.37123848110882696
# differential_evolution step 684: f(x)= 0.37123848110882696
# differential_evolution step 685: f(x)= 0.37123848110882696
# differential_evolution step 686: f(x)= 0.37123848110882696
# differential_evolution step 687: f(x)= 0.37123848110882696
# differential_evolution step 688: f(x)= 0.37123848110882696
# differential_evolution step 689: f(x)= 0.37123848110882696
# differential_evolution step 690: f(x)= 0.37123848110882696
# differential_evolution step 691: f(x)= 0.37123848110882696
# differential_evolution step 692: f(x)= 0.37123848110882696
# differential_evolution step 693: f(x)= 0.37123848110882696
# differential_evolution step 694: f(x)= 0.37123848110882696
# differential_evolution step 695: f(x)= 0.37123848110882696
# differential_evolution step 696: f(x)= 0.37123848110882696
# differential_evolution step 697: f(x)= 0.37123848110882696
# differential_evolution step 698: f(x)= 0.37123848110882696
# differential_evolution step 699: f(x)= 0.37123848110882696
# differential_evolution step 700: f(x)= 0.37123848110882696
# differential_evolution step 701: f(x)= 0.37123848110882696
# differential_evolution step 702: f(x)= 0.37123848110882696
# differential_evolution step 703: f(x)= 0.37123848110882696
# differential_evolution step 704: f(x)= 0.37123848110882696
# differential_evolution step 705: f(x)= 0.37123848110882696
# differential_evolution step 706: f(x)= 0.37123848110882696
# differential_evolution step 707: f(x)= 0.37123848110882696
# differential_evolution step 708: f(x)= 0.37123848110882696
# differential_evolution step 709: f(x)= 0.37123848110882696
# differential_evolution step 710: f(x)= 0.37123848110882696
# differential_evolution step 711: f(x)= 0.37123848110882696
# differential_evolution step 712: f(x)= 0.37123848110882696
# differential_evolution step 713: f(x)= 0.37123848110882696
# differential_evolution step 714: f(x)= 0.37123848110882696
# differential_evolution step 715: f(x)= 0.37123848110882696
# differential_evolution step 716: f(x)= 0.37123848110882696
# differential_evolution step 717: f(x)= 0.37123848110882696
# differential_evolution step 718: f(x)= 0.37123848110882696
# differential_evolution step 719: f(x)= 0.37123848110882696
# differential_evolution step 720: f(x)= 0.37123848110882696
# differential_evolution step 721: f(x)= 0.37123848110882696
# differential_evolution step 722: f(x)= 0.37123848110882696
# differential_evolution step 723: f(x)= 0.37123848110882696
# differential_evolution step 724: f(x)= 0.37123848110882696
# differential_evolution step 725: f(x)= 0.37123848110882696
# differential_evolution step 726: f(x)= 0.37123848110882696
# differential_evolution step 727: f(x)= 0.37123848110882696
# differential_evolution step 728: f(x)= 0.37123848110882696
# differential_evolution step 729: f(x)= 0.37123848110882696
# differential_evolution step 730: f(x)= 0.37123848110882696
# differential_evolution step 731: f(x)= 0.37123848110882696
# differential_evolution step 732: f(x)= 0.37123848110882696
# differential_evolution step 733: f(x)= 0.37123848110882696
# differential_evolution step 734: f(x)= 0.37123848110882696
# differential_evolution step 735: f(x)= 0.37123848110882696
# differential_evolution step 736: f(x)= 0.37123848110882696
# differential_evolution step 737: f(x)= 0.37123848110882696
# differential_evolution step 738: f(x)= 0.37123848110882696
# differential_evolution step 739: f(x)= 0.37123848110882696
# differential_evolution step 740: f(x)= 0.37123848110882696
# differential_evolution step 741: f(x)= 0.37123848110882696
# differential_evolution step 742: f(x)= 0.37123848110882696
# differential_evolution step 743: f(x)= 0.37123848110882696
# differential_evolution step 744: f(x)= 0.37123848110882696
# differential_evolution step 745: f(x)= 0.37123848110882696
# differential_evolution step 746: f(x)= 0.37123848110882696
# differential_evolution step 747: f(x)= 0.37123848110882696
# differential_evolution step 748: f(x)= 0.37123848110882696
# differential_evolution step 749: f(x)= 0.2710386452775565
# differential_evolution step 750: f(x)= 0.2710386452775565
# differential_evolution step 751: f(x)= 0.2710386452775565
# differential_evolution step 752: f(x)= 0.2710386452775565
# differential_evolution step 753: f(x)= 0.2710386452775565
# differential_evolution step 754: f(x)= 0.2710386452775565
# differential_evolution step 755: f(x)= 0.2710386452775565
# differential_evolution step 756: f(x)= 0.2710386452775565
# differential_evolution step 757: f(x)= 0.2710386452775565
# differential_evolution step 758: f(x)= 0.2710386452775565
# differential_evolution step 759: f(x)= 0.2710386452775565
# differential_evolution step 760: f(x)= 0.2710386452775565
# differential_evolution step 761: f(x)= 0.2710386452775565
# differential_evolution step 762: f(x)= 0.2710386452775565
# differential_evolution step 763: f(x)= 0.2710386452775565
# differential_evolution step 764: f(x)= 0.2710386452775565
# differential_evolution step 765: f(x)= 0.2710386452775565
# differential_evolution step 766: f(x)= 0.2710386452775565
# differential_evolution step 767: f(x)= 0.2710386452775565
# differential_evolution step 768: f(x)= 0.2710386452775565
# differential_evolution step 769: f(x)= 0.2710386452775565
# differential_evolution step 770: f(x)= 0.2710386452775565
# differential_evolution step 771: f(x)= 0.2710386452775565
# differential_evolution step 772: f(x)= 0.2710386452775565
# differential_evolution step 773: f(x)= 0.2710386452775565
# differential_evolution step 774: f(x)= 0.2710386452775565
# differential_evolution step 775: f(x)= 0.2710386452775565
# differential_evolution step 776: f(x)= 0.2710386452775565
# differential_evolution step 777: f(x)= 0.2710386452775565
# differential_evolution step 778: f(x)= 0.2710386452775565
# differential_evolution step 779: f(x)= 0.2710386452775565
# differential_evolution step 780: f(x)= 0.2710386452775565
# differential_evolution step 781: f(x)= 0.2710386452775565
# differential_evolution step 782: f(x)= 0.2710386452775565
# differential_evolution step 783: f(x)= 0.20811365267923895
# differential_evolution step 784: f(x)= 0.20811365267923895
# differential_evolution step 785: f(x)= 0.20811365267923895
# differential_evolution step 786: f(x)= 0.20811365267923895
# differential_evolution step 787: f(x)= 0.20811365267923895
# differential_evolution step 788: f(x)= 0.20811365267923895
# differential_evolution step 789: f(x)= 0.20811365267923895
# differential_evolution step 790: f(x)= 0.20811365267923895
# differential_evolution step 791: f(x)= 0.20811365267923895
# differential_evolution step 792: f(x)= 0.20811365267923895
# differential_evolution step 793: f(x)= 0.20811365267923895
# differential_evolution step 794: f(x)= 0.20811365267923895
# differential_evolution step 795: f(x)= 0.20811365267923895
# differential_evolution step 796: f(x)= 0.20811365267923895
# differential_evolution step 797: f(x)= 0.20811365267923895
# differential_evolution step 798: f(x)= 0.20811365267923895
# differential_evolution step 799: f(x)= 0.20811365267923895
# differential_evolution step 800: f(x)= 0.20811365267923895
# differential_evolution step 801: f(x)= 0.20811365267923895
# differential_evolution step 802: f(x)= 0.20811365267923895
# differential_evolution step 803: f(x)= 0.20811365267923895
# differential_evolution step 804: f(x)= 0.20811365267923895
# differential_evolution step 805: f(x)= 0.20811365267923895
# differential_evolution step 806: f(x)= 0.20811365267923895
# differential_evolution step 807: f(x)= 0.20811365267923895
# differential_evolution step 808: f(x)= 0.20811365267923895
# differential_evolution step 809: f(x)= 0.20811365267923895
# differential_evolution step 810: f(x)= 0.20811365267923895
# differential_evolution step 811: f(x)= 0.20811365267923895
# differential_evolution step 812: f(x)= 0.20811365267923895
# differential_evolution step 813: f(x)= 0.20811365267923895
# differential_evolution step 814: f(x)= 0.20811365267923895
# differential_evolution step 815: f(x)= 0.20811365267923895
# differential_evolution step 816: f(x)= 0.20811365267923895
# differential_evolution step 817: f(x)= 0.20811365267923895
# differential_evolution step 818: f(x)= 0.20811365267923895
# differential_evolution step 819: f(x)= 0.20811365267923895
# differential_evolution step 820: f(x)= 0.20811365267923895
# differential_evolution step 821: f(x)= 0.20811365267923895
# differential_evolution step 822: f(x)= 0.20806184906405797
# differential_evolution step 823: f(x)= 0.20806184906405797
# differential_evolution step 824: f(x)= 0.20806184906405797
# differential_evolution step 825: f(x)= 0.20806184906405797
# differential_evolution step 826: f(x)= 0.20806184906405797
# differential_evolution step 827: f(x)= 0.20806184906405797
# differential_evolution step 828: f(x)= 0.20806184906405797
# differential_evolution step 829: f(x)= 0.20806184906405797
# differential_evolution step 830: f(x)= 0.20806184906405797
# differential_evolution step 831: f(x)= 0.18907257250152285
# differential_evolution step 832: f(x)= 0.18907257250152285
# differential_evolution step 833: f(x)= 0.18907257250152285
# differential_evolution step 834: f(x)= 0.18907257250152285
# differential_evolution step 835: f(x)= 0.18907257250152285
# differential_evolution step 836: f(x)= 0.18907257250152285
# differential_evolution step 837: f(x)= 0.18907257250152285
# differential_evolution step 838: f(x)= 0.18907257250152285
# differential_evolution step 839: f(x)= 0.18907257250152285
# differential_evolution step 840: f(x)= 0.18907257250152285
# differential_evolution step 841: f(x)= 0.18907257250152285
# differential_evolution step 842: f(x)= 0.18907257250152285
# differential_evolution step 843: f(x)= 0.18907257250152285
# differential_evolution step 844: f(x)= 0.18907257250152285
# differential_evolution step 845: f(x)= 0.16638707234679262
# differential_evolution step 846: f(x)= 0.16638707234679262
# differential_evolution step 847: f(x)= 0.16638707234679262
# differential_evolution step 848: f(x)= 0.16638707234679262
# differential_evolution step 849: f(x)= 0.16638707234679262
# differential_evolution step 850: f(x)= 0.16638707234679262
# differential_evolution step 851: f(x)= 0.16638707234679262
# differential_evolution step 852: f(x)= 0.16638707234679262
# differential_evolution step 853: f(x)= 0.16638707234679262
# differential_evolution step 854: f(x)= 0.16638707234679262
# differential_evolution step 855: f(x)= 0.16638707234679262
# differential_evolution step 856: f(x)= 0.16638707234679262
# differential_evolution step 857: f(x)= 0.16638707234679262
# differential_evolution step 858: f(x)= 0.16638707234679262
# differential_evolution step 859: f(x)= 0.16638707234679262
# differential_evolution step 860: f(x)= 0.16638707234679262
# differential_evolution step 861: f(x)= 0.16638707234679262
# differential_evolution step 862: f(x)= 0.16638707234679262
# differential_evolution step 863: f(x)= 0.16638707234679262
# differential_evolution step 864: f(x)= 0.16638707234679262
# differential_evolution step 865: f(x)= 0.16638707234679262
# differential_evolution step 866: f(x)= 0.16638707234679262
# differential_evolution step 867: f(x)= 0.16638707234679262
# differential_evolution step 868: f(x)= 0.16638707234679262
# differential_evolution step 869: f(x)= 0.16638707234679262
# differential_evolution step 870: f(x)= 0.16638707234679262
# differential_evolution step 871: f(x)= 0.16638707234679262
# differential_evolution step 872: f(x)= 0.16638707234679262
# differential_evolution step 873: f(x)= 0.16638707234679262
# differential_evolution step 874: f(x)= 0.16638707234679262
# differential_evolution step 875: f(x)= 0.16638707234679262
# differential_evolution step 876: f(x)= 0.16638707234679262
# differential_evolution step 877: f(x)= 0.16638707234679262
# differential_evolution step 878: f(x)= 0.16638707234679262
# differential_evolution step 879: f(x)= 0.16638707234679262
# differential_evolution step 880: f(x)= 0.16638707234679262
# differential_evolution step 881: f(x)= 0.16638707234679262
# differential_evolution step 882: f(x)= 0.16638707234679262
# differential_evolution step 883: f(x)= 0.16638707234679262
# differential_evolution step 884: f(x)= 0.16638707234679262
# differential_evolution step 885: f(x)= 0.16638707234679262
# differential_evolution step 886: f(x)= 0.16638707234679262
# differential_evolution step 887: f(x)= 0.16638707234679262
# differential_evolution step 888: f(x)= 0.16638707234679262
# differential_evolution step 889: f(x)= 0.16638707234679262
# differential_evolution step 890: f(x)= 0.16638707234679262
# differential_evolution step 891: f(x)= 0.16638707234679262
# differential_evolution step 892: f(x)= 0.16638707234679262
# differential_evolution step 893: f(x)= 0.16638707234679262
# differential_evolution step 894: f(x)= 0.16638707234679262
# differential_evolution step 895: f(x)= 0.16638707234679262
# differential_evolution step 896: f(x)= 0.16638707234679262
# differential_evolution step 897: f(x)= 0.16638707234679262
# differential_evolution step 898: f(x)= 0.16638707234679262
# differential_evolution step 899: f(x)= 0.16638707234679262
# differential_evolution step 900: f(x)= 0.16638707234679262
# differential_evolution step 901: f(x)= 0.16638707234679262
# differential_evolution step 902: f(x)= 0.16638707234679262
# differential_evolution step 903: f(x)= 0.16638707234679262
# differential_evolution step 904: f(x)= 0.16638707234679262
# differential_evolution step 905: f(x)= 0.16638707234679262
# differential_evolution step 906: f(x)= 0.16638707234679262
# differential_evolution step 907: f(x)= 0.16638707234679262
# differential_evolution step 908: f(x)= 0.16638707234679262
# differential_evolution step 909: f(x)= 0.16638707234679262
# differential_evolution step 910: f(x)= 0.16638707234679262
# differential_evolution step 911: f(x)= 0.16638707234679262
# differential_evolution step 912: f(x)= 0.16638707234679262
# differential_evolution step 913: f(x)= 0.16638707234679262
# differential_evolution step 914: f(x)= 0.16638707234679262
# differential_evolution step 915: f(x)= 0.16638707234679262
# differential_evolution step 916: f(x)= 0.16638707234679262
# differential_evolution step 917: f(x)= 0.16638707234679262
# differential_evolution step 918: f(x)= 0.16638707234679262
# differential_evolution step 919: f(x)= 0.16638707234679262
# differential_evolution step 920: f(x)= 0.16638707234679262
# differential_evolution step 921: f(x)= 0.16638707234679262
# differential_evolution step 922: f(x)= 0.16638707234679262
# differential_evolution step 923: f(x)= 0.16638707234679262
# differential_evolution step 924: f(x)= 0.16638707234679262
# differential_evolution step 925: f(x)= 0.16638707234679262
# differential_evolution step 926: f(x)= 0.16638707234679262
# differential_evolution step 927: f(x)= 0.16638707234679262
# differential_evolution step 928: f(x)= 0.16638707234679262
# differential_evolution step 929: f(x)= 0.16638707234679262
# differential_evolution step 930: f(x)= 0.16638707234679262
# differential_evolution step 931: f(x)= 0.16638707234679262
# differential_evolution step 932: f(x)= 0.16638707234679262
# differential_evolution step 933: f(x)= 0.16638707234679262
# differential_evolution step 934: f(x)= 0.16638707234679262
# differential_evolution step 935: f(x)= 0.16638707234679262
# differential_evolution step 936: f(x)= 0.16638707234679262
# differential_evolution step 937: f(x)= 0.16638707234679262
# differential_evolution step 938: f(x)= 0.16638707234679262
# differential_evolution step 939: f(x)= 0.16638707234679262
# differential_evolution step 940: f(x)= 0.16638707234679262
# differential_evolution step 941: f(x)= 0.16638707234679262
# differential_evolution step 942: f(x)= 0.16638707234679262
# differential_evolution step 943: f(x)= 0.16638707234679262
# differential_evolution step 944: f(x)= 0.16638707234679262
# differential_evolution step 945: f(x)= 0.16638707234679262
# differential_evolution step 946: f(x)= 0.16638707234679262
# differential_evolution step 947: f(x)= 0.16638707234679262
# differential_evolution step 948: f(x)= 0.16638707234679262
# differential_evolution step 949: f(x)= 0.16638707234679262
# differential_evolution step 950: f(x)= 0.16638707234679262
# differential_evolution step 951: f(x)= 0.16638707234679262
# differential_evolution step 952: f(x)= 0.16638707234679262
# differential_evolution step 953: f(x)= 0.16638707234679262
# differential_evolution step 954: f(x)= 0.16638707234679262
# differential_evolution step 955: f(x)= 0.1559010659483811
# differential_evolution step 956: f(x)= 0.1559010659483811
# differential_evolution step 957: f(x)= 0.1559010659483811
# differential_evolution step 958: f(x)= 0.1559010659483811
# differential_evolution step 959: f(x)= 0.1559010659483811
# differential_evolution step 960: f(x)= 0.1559010659483811
# differential_evolution step 961: f(x)= 0.1559010659483811
# differential_evolution step 962: f(x)= 0.1559010659483811
# differential_evolution step 963: f(x)= 0.1559010659483811
# differential_evolution step 964: f(x)= 0.1559010659483811
# differential_evolution step 965: f(x)= 0.1559010659483811
# differential_evolution step 966: f(x)= 0.1559010659483811
# differential_evolution step 967: f(x)= 0.1559010659483811
# differential_evolution step 968: f(x)= 0.1559010659483811
# differential_evolution step 969: f(x)= 0.1559010659483811
# differential_evolution step 970: f(x)= 0.1559010659483811
# differential_evolution step 971: f(x)= 0.1559010659483811
# differential_evolution step 972: f(x)= 0.1559010659483811
# differential_evolution step 973: f(x)= 0.1559010659483811
# differential_evolution step 974: f(x)= 0.1559010659483811
# differential_evolution step 975: f(x)= 0.1559010659483811
# differential_evolution step 976: f(x)= 0.1559010659483811
# differential_evolution step 977: f(x)= 0.1559010659483811
# differential_evolution step 978: f(x)= 0.1559010659483811
# differential_evolution step 979: f(x)= 0.1559010659483811
# differential_evolution step 980: f(x)= 0.1559010659483811
# differential_evolution step 981: f(x)= 0.1559010659483811
# differential_evolution step 982: f(x)= 0.15441868744795953
# differential_evolution step 983: f(x)= 0.15441868744795953
# differential_evolution step 984: f(x)= 0.15441868744795953
# differential_evolution step 985: f(x)= 0.15441868744795953
# differential_evolution step 986: f(x)= 0.15441868744795953
# differential_evolution step 987: f(x)= 0.15441868744795953
# differential_evolution step 988: f(x)= 0.15441868744795953
# differential_evolution step 989: f(x)= 0.15441868744795953
# differential_evolution step 990: f(x)= 0.15441868744795953
# differential_evolution step 991: f(x)= 0.15441868744795953
# differential_evolution step 992: f(x)= 0.15441868744795953
# differential_evolution step 993: f(x)= 0.15441868744795953
# differential_evolution step 994: f(x)= 0.15441868744795953
# differential_evolution step 995: f(x)= 0.15216119152254037
# differential_evolution step 996: f(x)= 0.14508364787765432
# differential_evolution step 997: f(x)= 0.14508364787765432
# differential_evolution step 998: f(x)= 0.14508364787765432
# differential_evolution step 999: f(x)= 0.14508364787765432
# differential_evolution step 1000: f(x)= 0.14508364787765432
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution: [2.08014340e-01 1.01862143e+01 1.25137994e+00 5.64361001e+01
#  1.18899277e-01 9.93422256e+00 1.52127659e+00 8.63773567e+01
#  6.23639319e-02 1.06424801e+01 1.11763654e+00 1.49438354e+01
#  2.38332477e-02 8.25508846e+00 2.36522624e+00 3.55843509e+01
#  3.29479069e-01 2.77341969e+00 2.70217115e-01 6.72795770e+01
#  3.63576967e-02 4.96219007e+01 1.51829905e+00 4.93712206e+01
#  4.81454766e+00 1.81937435e-05 4.71063092e+00 3.09204893e+01]
# Chi quadro minimo: 0.11381130362234593

# %%
# Plots:
params_curve_7, covariance_7 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params7, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[6], red_chi[6] = save_params(params_curve_7, covariance_7, radial_profile_HA, radial_profile_error_HA, x_axes, 7, 
                                       line_name="Seven", output_prefix="fit")

aic[6] = AIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
bic[6] = BIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
print(aic[6], chi_quadr[6], bic[6], len(best_params7))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_7)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[20:24]),  linestyle='--', label='Sérsic 6')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[24:28]),  linestyle='--', label='Sérsic 7')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_7', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_17208\698150684.py:13: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.3865, r_e=5.2341, n=0.8612, x_0=56.3490
# Sérsic 2: I_e=0.0779, r_e=12.8202, n=1.8216, x_0=86.3546
# Sérsic 3: I_e=0.1214, r_e=5.2270, n=0.6328, x_0=14.8863
# Sérsic 4: I_e=0.0100, r_e=7.1234, n=3.6752, x_0=35.8965
# Sérsic 5: I_e=0.3094, r_e=3.3900, n=0.4457, x_0=66.9312
# Sérsic 6: I_e=0.0319, r_e=75.1151, n=1.7549, x_0=48.0825
# Sérsic 7: I_e=5.2556, r_e=0.0000, n=7.8197, x_0=30.9205
# [2.68175855e-01 3.89874151e+00 4.61031896e-01 1.40968226e-01
#  3.82204374e-02 5.50436801e+00 3.45966178e-01 8.84848049e-02
#  3.65068252e-02 1.58068369e+00 2.36833738e-01 2.75756307e-01
#  2.73814440e-01 1.23187399e+02 3.93112703e+01 9.03972791e-03
#  8.90787920e-02 5.31687624e-01 1.39506654e-01 5.87821104e-01
#  3.36659093e-02 5.99896557e+01 4.88395538e-01 6.23605470e-01
#  3.77199382e+06 1.43762755e+01 6.24570772e+06 6.89360250e+00]
# 4.334912894471197
# 83.20815233109091 4.334912894471197 133.27967810213775 28
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6, 7]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N', bbox_inches='tight')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N', bbox_inches='tight')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log', bbox_inches='tight')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
