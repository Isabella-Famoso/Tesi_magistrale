# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA (ampiezza dell'intervallo sulle x è +- la metà del seeing) e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32

# %%
image_cut = image[70:170, 0:1890]
image_error_cut = image_error[70:170, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.00328
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/PSF/Real_seeing_NGC3773.txt")
sigmas = seeing / 2.35
n_component = 3
print(sigmas)
# Out:
# [1.01016511 1.12309039 1.00840577 0.99664427 1.1197505  1.01319149]

# %%
l_HA
# Out:
# 6584.52664

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[70:170, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 28)*(y < 38)
mask_wv = wv > 4450.5
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])# +
        #sersic_1d(x_hr, *params[12:16]) +
        #sersic_1d(x_hr, *params[16:20]) #+
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 58)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 58)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (43, 45),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 12097.572224923311
# differential_evolution step 2: f(x)= 12097.572224923311
# differential_evolution step 3: f(x)= 12097.572224923311
# differential_evolution step 4: f(x)= 12097.572224923311
# differential_evolution step 5: f(x)= 12097.572224923311
# differential_evolution step 6: f(x)= 12097.572224923311
# differential_evolution step 7: f(x)= 12097.572224923311
# differential_evolution step 8: f(x)= 1792.9655290920073
# differential_evolution step 9: f(x)= 1792.9655290920073
# differential_evolution step 10: f(x)= 1792.9655290920073
# differential_evolution step 11: f(x)= 1792.9655290920073
# differential_evolution step 12: f(x)= 1792.9655290920073
# differential_evolution step 13: f(x)= 1792.9655290920073
# differential_evolution step 14: f(x)= 1792.9655290920073
# differential_evolution step 15: f(x)= 1792.9655290920073
# differential_evolution step 16: f(x)= 1792.9655290920073
# differential_evolution step 17: f(x)= 1792.9655290920073
# differential_evolution step 18: f(x)= 1792.9655290920073
# differential_evolution step 19: f(x)= 1415.7456342873202
# differential_evolution step 20: f(x)= 1415.7456342873202
# differential_evolution step 21: f(x)= 1412.5624514943934
# differential_evolution step 22: f(x)= 1412.5624514943934
# differential_evolution step 23: f(x)= 1412.5624514943934
# differential_evolution step 24: f(x)= 1412.5624514943934
# differential_evolution step 25: f(x)= 1412.5624514943934
# differential_evolution step 26: f(x)= 1098.3226406792699
# differential_evolution step 27: f(x)= 1088.1104004978968
# differential_evolution step 28: f(x)= 1075.0449640904496
# differential_evolution step 29: f(x)= 1075.0449640904496
# differential_evolution step 30: f(x)= 895.6886959843499
# differential_evolution step 31: f(x)= 849.7096421309827
# differential_evolution step 32: f(x)= 849.7096421309827
# differential_evolution step 33: f(x)= 849.7096421309827
# differential_evolution step 34: f(x)= 708.9727694188258
# differential_evolution step 35: f(x)= 708.9727694188258
# differential_evolution step 36: f(x)= 708.9727694188258
# differential_evolution step 37: f(x)= 708.9727694188258
# differential_evolution step 38: f(x)= 689.5054674782327
# differential_evolution step 39: f(x)= 689.5054674782327
# differential_evolution step 40: f(x)= 689.5054674782327
# differential_evolution step 41: f(x)= 578.3734137377245
# differential_evolution step 42: f(x)= 578.3734137377245
# differential_evolution step 43: f(x)= 578.3734137377245
# differential_evolution step 44: f(x)= 578.3734137377245
# differential_evolution step 45: f(x)= 556.7269081834769
# differential_evolution step 46: f(x)= 556.7269081834769
# differential_evolution step 47: f(x)= 556.7269081834769
# differential_evolution step 48: f(x)= 556.7269081834769
# differential_evolution step 49: f(x)= 556.7269081834769
# differential_evolution step 50: f(x)= 459.0082986226896
# differential_evolution step 51: f(x)= 459.0082986226896
# differential_evolution step 52: f(x)= 443.97394502477226
# differential_evolution step 53: f(x)= 443.97394502477226
# differential_evolution step 54: f(x)= 443.97394502477226
# differential_evolution step 55: f(x)= 443.97394502477226
# differential_evolution step 56: f(x)= 443.97394502477226
# differential_evolution step 57: f(x)= 373.55194381425326
# differential_evolution step 58: f(x)= 362.1822752325016
# differential_evolution step 59: f(x)= 362.1822752325016
# differential_evolution step 60: f(x)= 362.1822752325016
# differential_evolution step 61: f(x)= 362.1822752325016
# differential_evolution step 62: f(x)= 362.1822752325016
# differential_evolution step 63: f(x)= 362.1822752325016
# differential_evolution step 64: f(x)= 351.9437727953478
# differential_evolution step 65: f(x)= 351.9437727953478
# differential_evolution step 66: f(x)= 351.9437727953478
# differential_evolution step 67: f(x)= 351.9437727953478
# differential_evolution step 68: f(x)= 351.9437727953478
# differential_evolution step 69: f(x)= 351.9437727953478
# differential_evolution step 70: f(x)= 351.9437727953478
# differential_evolution step 71: f(x)= 351.9437727953478
# differential_evolution step 72: f(x)= 347.3017711622493
# differential_evolution step 73: f(x)= 347.3017711622493
# differential_evolution step 74: f(x)= 315.58849321266706
# differential_evolution step 75: f(x)= 288.57892350473077
# differential_evolution step 76: f(x)= 288.57892350473077
# differential_evolution step 77: f(x)= 280.8549039967701
# differential_evolution step 78: f(x)= 267.00978296081854
# differential_evolution step 79: f(x)= 253.84765665988627
# differential_evolution step 80: f(x)= 253.84765665988627
# differential_evolution step 81: f(x)= 253.84765665988627
# differential_evolution step 82: f(x)= 253.84765665988627
# differential_evolution step 83: f(x)= 253.84765665988627
# differential_evolution step 84: f(x)= 218.25335061622383
# differential_evolution step 85: f(x)= 218.25335061622383
# differential_evolution step 86: f(x)= 218.25335061622383
# differential_evolution step 87: f(x)= 218.25335061622383
# differential_evolution step 88: f(x)= 218.25335061622383
# differential_evolution step 89: f(x)= 218.25335061622383
# differential_evolution step 90: f(x)= 218.25335061622383
# differential_evolution step 91: f(x)= 218.25335061622383
# differential_evolution step 92: f(x)= 218.25335061622383
# differential_evolution step 93: f(x)= 194.14960420926255
# differential_evolution step 94: f(x)= 194.14960420926255
# differential_evolution step 95: f(x)= 194.14960420926255
# differential_evolution step 96: f(x)= 194.14960420926255
# differential_evolution step 97: f(x)= 194.14960420926255
# differential_evolution step 98: f(x)= 182.89506966927414
# differential_evolution step 99: f(x)= 182.89506966927414
# differential_evolution step 100: f(x)= 182.89506966927414
# differential_evolution step 101: f(x)= 182.89506966927414
# differential_evolution step 102: f(x)= 182.89506966927414
# differential_evolution step 103: f(x)= 182.89506966927414
# differential_evolution step 104: f(x)= 182.89506966927414
# differential_evolution step 105: f(x)= 182.89506966927414
# differential_evolution step 106: f(x)= 182.89506966927414
# differential_evolution step 107: f(x)= 182.89506966927414
# differential_evolution step 108: f(x)= 182.89506966927414
# differential_evolution step 109: f(x)= 169.7058119239319
# differential_evolution step 110: f(x)= 161.07558278324422
# differential_evolution step 111: f(x)= 161.07558278324422
# differential_evolution step 112: f(x)= 161.07558278324422
# differential_evolution step 113: f(x)= 161.07558278324422
# differential_evolution step 114: f(x)= 159.96417416888306
# differential_evolution step 115: f(x)= 159.96417416888306
# differential_evolution step 116: f(x)= 159.96417416888306
# differential_evolution step 117: f(x)= 159.96417416888306
# differential_evolution step 118: f(x)= 159.96417416888306
# differential_evolution step 119: f(x)= 154.60440934961045
# differential_evolution step 120: f(x)= 154.60440934961045
# differential_evolution step 121: f(x)= 154.60440934961045
# differential_evolution step 122: f(x)= 154.28627252158887
# differential_evolution step 123: f(x)= 142.63701913827796
# differential_evolution step 124: f(x)= 142.63701913827796
# differential_evolution step 125: f(x)= 142.63701913827796
# differential_evolution step 126: f(x)= 142.63701913827796
# differential_evolution step 127: f(x)= 141.9217579945004
# differential_evolution step 128: f(x)= 141.9217579945004
# differential_evolution step 129: f(x)= 141.9217579945004
# differential_evolution step 130: f(x)= 141.9217579945004
# differential_evolution step 131: f(x)= 141.9217579945004
# differential_evolution step 132: f(x)= 141.9217579945004
# differential_evolution step 133: f(x)= 134.3366047218933
# differential_evolution step 134: f(x)= 134.3366047218933
# differential_evolution step 135: f(x)= 134.3366047218933
# differential_evolution step 136: f(x)= 134.3366047218933
# differential_evolution step 137: f(x)= 134.3366047218933
# differential_evolution step 138: f(x)= 134.3366047218933
# differential_evolution step 139: f(x)= 134.3366047218933
# differential_evolution step 140: f(x)= 134.3366047218933
# differential_evolution step 141: f(x)= 134.3366047218933
# differential_evolution step 142: f(x)= 134.3366047218933
# differential_evolution step 143: f(x)= 134.3366047218933
# differential_evolution step 144: f(x)= 134.3366047218933
# differential_evolution step 145: f(x)= 127.05621005731099
# differential_evolution step 146: f(x)= 127.05621005731099
# differential_evolution step 147: f(x)= 127.05621005731099
# differential_evolution step 148: f(x)= 127.05621005731099
# differential_evolution step 149: f(x)= 127.05621005731099
# differential_evolution step 150: f(x)= 127.05621005731099
# differential_evolution step 151: f(x)= 127.05621005731099
# differential_evolution step 152: f(x)= 125.67464720894945
# differential_evolution step 153: f(x)= 125.67464720894945
# differential_evolution step 154: f(x)= 125.67464720894945
# differential_evolution step 155: f(x)= 125.67464720894945
# differential_evolution step 156: f(x)= 125.67464720894945
# differential_evolution step 157: f(x)= 122.80232278096443
# differential_evolution step 158: f(x)= 122.80232278096443
# differential_evolution step 159: f(x)= 122.80232278096443
# differential_evolution step 160: f(x)= 122.80232278096443
# differential_evolution step 161: f(x)= 122.80232278096443
# differential_evolution step 162: f(x)= 122.80232278096443
# differential_evolution step 163: f(x)= 122.80232278096443
# differential_evolution step 164: f(x)= 122.80232278096443
# differential_evolution step 165: f(x)= 122.80232278096443
# differential_evolution step 166: f(x)= 119.35848643057302
# differential_evolution step 167: f(x)= 119.35848643057302
# differential_evolution step 168: f(x)= 119.35848643057302
# differential_evolution step 169: f(x)= 119.35848643057302
# differential_evolution step 170: f(x)= 119.35848643057302
# differential_evolution step 171: f(x)= 118.15106003144649
# differential_evolution step 172: f(x)= 118.15106003144649
# differential_evolution step 173: f(x)= 118.15106003144649
# differential_evolution step 174: f(x)= 118.15106003144649
# differential_evolution step 175: f(x)= 117.47895035999086
# differential_evolution step 176: f(x)= 117.47895035999086
# differential_evolution step 177: f(x)= 117.47895035999086
# differential_evolution step 178: f(x)= 117.47895035999086
# differential_evolution step 179: f(x)= 117.47895035999086
# differential_evolution step 180: f(x)= 117.41435302242125
# differential_evolution step 181: f(x)= 117.41435302242125
# differential_evolution step 182: f(x)= 117.41435302242125
# differential_evolution step 183: f(x)= 117.41435302242125
# differential_evolution step 184: f(x)= 117.41435302242125
# differential_evolution step 185: f(x)= 116.17610904097465
# differential_evolution step 186: f(x)= 116.17610904097465
# differential_evolution step 187: f(x)= 116.17610904097465
# differential_evolution step 188: f(x)= 116.17610904097465
# differential_evolution step 189: f(x)= 114.61135375725502
# differential_evolution step 190: f(x)= 114.61135375725502
# differential_evolution step 191: f(x)= 114.61135375725502
# differential_evolution step 192: f(x)= 114.61135375725502
# differential_evolution step 193: f(x)= 114.61135375725502
# differential_evolution step 194: f(x)= 114.61135375725502
# differential_evolution step 195: f(x)= 114.61135375725502
# differential_evolution step 196: f(x)= 114.61135375725502
# differential_evolution step 197: f(x)= 114.61135375725502
# differential_evolution step 198: f(x)= 114.61135375725502
# differential_evolution step 199: f(x)= 114.61135375725502
# differential_evolution step 200: f(x)= 114.61135375725502
# differential_evolution step 201: f(x)= 114.61135375725502
# differential_evolution step 202: f(x)= 114.61135375725502
# differential_evolution step 203: f(x)= 114.61135375725502
# differential_evolution step 204: f(x)= 114.61135375725502
# differential_evolution step 205: f(x)= 114.61135375725502
# differential_evolution step 206: f(x)= 114.61135375725502
# differential_evolution step 207: f(x)= 114.61135375725502
# differential_evolution step 208: f(x)= 114.61135375725502
# differential_evolution step 209: f(x)= 114.61135375725502
# differential_evolution step 210: f(x)= 114.39915248590607
# differential_evolution step 211: f(x)= 114.39915248590607
# differential_evolution step 212: f(x)= 114.39915248590607
# differential_evolution step 213: f(x)= 114.39915248590607
# differential_evolution step 214: f(x)= 114.39915248590607
# differential_evolution step 215: f(x)= 114.39915248590607
# differential_evolution step 216: f(x)= 114.39915248590607
# differential_evolution step 217: f(x)= 114.39915248590607
# differential_evolution step 218: f(x)= 114.39915248590607
# differential_evolution step 219: f(x)= 114.39915248590607
# differential_evolution step 220: f(x)= 114.39915248590607
# differential_evolution step 221: f(x)= 114.39915248590607
# differential_evolution step 222: f(x)= 112.95375854223258
# differential_evolution step 223: f(x)= 112.95375854223258
# differential_evolution step 224: f(x)= 112.95375854223258
# differential_evolution step 225: f(x)= 112.95375854223258
# differential_evolution step 226: f(x)= 112.95375854223258
# differential_evolution step 227: f(x)= 112.95375854223258
# differential_evolution step 228: f(x)= 112.95375854223258
# differential_evolution step 229: f(x)= 112.95375854223258
# differential_evolution step 230: f(x)= 112.95375854223258
# differential_evolution step 231: f(x)= 112.38765039373335
# differential_evolution step 232: f(x)= 112.38765039373335
# differential_evolution step 233: f(x)= 112.38765039373335
# differential_evolution step 234: f(x)= 112.38765039373335
# differential_evolution step 235: f(x)= 112.38765039373335
# differential_evolution step 236: f(x)= 112.38765039373335
# differential_evolution step 237: f(x)= 112.37957967695581
# differential_evolution step 238: f(x)= 112.37957967695581
# differential_evolution step 239: f(x)= 112.37957967695581
# differential_evolution step 240: f(x)= 112.37957967695581
# differential_evolution step 241: f(x)= 112.37957967695581
# differential_evolution step 242: f(x)= 112.37957967695581
# differential_evolution step 243: f(x)= 112.37957967695581
# differential_evolution step 244: f(x)= 110.87362620120335
# differential_evolution step 245: f(x)= 110.87362620120335
# differential_evolution step 246: f(x)= 110.87362620120335
# differential_evolution step 247: f(x)= 110.87362620120335
# differential_evolution step 248: f(x)= 110.87362620120335
# differential_evolution step 249: f(x)= 110.87362620120335
# differential_evolution step 250: f(x)= 110.87362620120335
# differential_evolution step 251: f(x)= 110.87362620120335
# differential_evolution step 252: f(x)= 110.87362620120335
# differential_evolution step 253: f(x)= 110.87362620120335
# differential_evolution step 254: f(x)= 110.87362620120335
# differential_evolution step 255: f(x)= 110.87362620120335
# differential_evolution step 256: f(x)= 110.87362620120335
# differential_evolution step 257: f(x)= 110.87362620120335
# differential_evolution step 258: f(x)= 110.63557722319905
# differential_evolution step 259: f(x)= 110.63557722319905
# differential_evolution step 260: f(x)= 110.63557722319905
# differential_evolution step 261: f(x)= 110.44186007849831
# differential_evolution step 262: f(x)= 110.44186007849831
# differential_evolution step 263: f(x)= 110.42710190398049
# differential_evolution step 264: f(x)= 110.42710190398049
# differential_evolution step 265: f(x)= 110.42710190398049
# differential_evolution step 266: f(x)= 110.42710190398049
# differential_evolution step 267: f(x)= 110.42710190398049
# differential_evolution step 268: f(x)= 110.42710190398049
# differential_evolution step 269: f(x)= 110.42710190398049
# differential_evolution step 270: f(x)= 110.42710190398049
# differential_evolution step 271: f(x)= 110.42710190398049
# differential_evolution step 272: f(x)= 110.42710190398049
# differential_evolution step 273: f(x)= 110.42710190398049
# differential_evolution step 274: f(x)= 110.42710190398049
# differential_evolution step 275: f(x)= 110.42710190398049
# differential_evolution step 276: f(x)= 109.92377733868568
# differential_evolution step 277: f(x)= 109.92377733868568
# differential_evolution step 278: f(x)= 109.92377733868568
# differential_evolution step 279: f(x)= 109.92377733868568
# differential_evolution step 280: f(x)= 109.92377733868568
# differential_evolution step 281: f(x)= 109.92377733868568
# differential_evolution step 282: f(x)= 109.92377733868568
# differential_evolution step 283: f(x)= 109.06858847814888
# differential_evolution step 284: f(x)= 109.06858847814888
# differential_evolution step 285: f(x)= 109.06858847814888
# differential_evolution step 286: f(x)= 109.06858847814888
# differential_evolution step 287: f(x)= 109.06858847814888
# differential_evolution step 288: f(x)= 109.06858847814888
# differential_evolution step 289: f(x)= 109.06858847814888
# differential_evolution step 290: f(x)= 109.06858847814888
# differential_evolution step 291: f(x)= 109.06858847814888
# differential_evolution step 292: f(x)= 109.06858847814888
# differential_evolution step 293: f(x)= 109.06858847814888
# differential_evolution step 294: f(x)= 109.06858847814888
# differential_evolution step 295: f(x)= 109.06858847814888
# differential_evolution step 296: f(x)= 109.06858847814888
# differential_evolution step 297: f(x)= 109.06858847814888
# differential_evolution step 298: f(x)= 109.06858847814888
# differential_evolution step 299: f(x)= 109.06858847814888
# differential_evolution step 300: f(x)= 109.06858847814888
# differential_evolution step 301: f(x)= 109.06858847814888
# differential_evolution step 302: f(x)= 109.06858847814888
# differential_evolution step 303: f(x)= 109.06858847814888
# differential_evolution step 304: f(x)= 109.06858847814888
# differential_evolution step 305: f(x)= 109.06858847814888
# differential_evolution step 306: f(x)= 108.93214894389989
# differential_evolution step 307: f(x)= 108.93214894389989
# differential_evolution step 308: f(x)= 108.93214894389989
# differential_evolution step 309: f(x)= 108.93214894389989
# differential_evolution step 310: f(x)= 108.93214894389989
# differential_evolution step 311: f(x)= 108.93214894389989
# differential_evolution step 312: f(x)= 108.93214894389989
# differential_evolution step 313: f(x)= 108.93214894389989
# differential_evolution step 314: f(x)= 108.76511451608643
# differential_evolution step 315: f(x)= 108.76511451608643
# differential_evolution step 316: f(x)= 108.76511451608643
# differential_evolution step 317: f(x)= 108.76511451608643
# differential_evolution step 318: f(x)= 108.76511451608643
# differential_evolution step 319: f(x)= 108.76511451608643
# differential_evolution step 320: f(x)= 108.55125085109825
# differential_evolution step 321: f(x)= 108.55125085109825
# differential_evolution step 322: f(x)= 108.55125085109825
# differential_evolution step 323: f(x)= 108.39293968516634
# differential_evolution step 324: f(x)= 108.39293968516634
# differential_evolution step 325: f(x)= 108.39293968516634
# differential_evolution step 326: f(x)= 108.39293968516634
# differential_evolution step 327: f(x)= 108.39293968516634
# differential_evolution step 328: f(x)= 108.39293968516634
# differential_evolution step 329: f(x)= 108.39293968516634
# differential_evolution step 330: f(x)= 108.39293968516634
# differential_evolution step 331: f(x)= 108.39293968516634
# differential_evolution step 332: f(x)= 108.39293968516634
# differential_evolution step 333: f(x)= 108.39293968516634
# differential_evolution step 334: f(x)= 108.39293968516634
# differential_evolution step 335: f(x)= 108.39293968516634
# differential_evolution step 336: f(x)= 108.39293968516634
# differential_evolution step 337: f(x)= 108.39293968516634
# differential_evolution step 338: f(x)= 108.14864097754835
# differential_evolution step 339: f(x)= 108.14864097754835
# differential_evolution step 340: f(x)= 108.14864097754835
# differential_evolution step 341: f(x)= 108.04233845772411
# differential_evolution step 342: f(x)= 107.89237461296011
# differential_evolution step 343: f(x)= 107.89237461296011
# differential_evolution step 344: f(x)= 107.89237461296011
# differential_evolution step 345: f(x)= 107.89237461296011
# differential_evolution step 346: f(x)= 107.89237461296011
# differential_evolution step 347: f(x)= 107.89237461296011
# differential_evolution step 348: f(x)= 107.89237461296011
# differential_evolution step 349: f(x)= 107.89237461296011
# differential_evolution step 350: f(x)= 107.89237461296011
# differential_evolution step 351: f(x)= 107.89237461296011
# differential_evolution step 352: f(x)= 107.89237461296011
# differential_evolution step 353: f(x)= 107.89237461296011
# differential_evolution step 354: f(x)= 107.89237461296011
# differential_evolution step 355: f(x)= 107.89237461296011
# differential_evolution step 356: f(x)= 107.89237461296011
# differential_evolution step 357: f(x)= 107.89237461296011
# differential_evolution step 358: f(x)= 107.89237461296011
# differential_evolution step 359: f(x)= 107.89237461296011
# differential_evolution step 360: f(x)= 107.89237461296011
# differential_evolution step 361: f(x)= 107.89237461296011
# differential_evolution step 362: f(x)= 107.89237461296011
# differential_evolution step 363: f(x)= 107.89237461296011
# differential_evolution step 364: f(x)= 107.89237461296011
# differential_evolution step 365: f(x)= 107.89237461296011
# differential_evolution step 366: f(x)= 107.89237461296011
# differential_evolution step 367: f(x)= 107.89237461296011
# differential_evolution step 368: f(x)= 107.89237461296011
# differential_evolution step 369: f(x)= 107.89237461296011
# differential_evolution step 370: f(x)= 107.89237461296011
# differential_evolution step 371: f(x)= 107.89237461296011
# differential_evolution step 372: f(x)= 107.89237461296011
# differential_evolution step 373: f(x)= 107.89237461296011
# differential_evolution step 374: f(x)= 107.89237461296011
# differential_evolution step 375: f(x)= 107.89237461296011
# differential_evolution step 376: f(x)= 107.89237461296011
# differential_evolution step 377: f(x)= 107.89237461296011
# differential_evolution step 378: f(x)= 107.89237461296011
# differential_evolution step 379: f(x)= 107.89237461296011
# differential_evolution step 380: f(x)= 107.89237461296011
# differential_evolution step 381: f(x)= 107.89237461296011
# differential_evolution step 382: f(x)= 107.89237461296011
# differential_evolution step 383: f(x)= 107.89237461296011
# differential_evolution step 384: f(x)= 107.89237461296011
# differential_evolution step 385: f(x)= 107.89237461296011
# differential_evolution step 386: f(x)= 107.89237461296011
# differential_evolution step 387: f(x)= 107.89237461296011
# differential_evolution step 388: f(x)= 107.89237461296011
# differential_evolution step 389: f(x)= 107.89237461296011
# differential_evolution step 390: f(x)= 107.89237461296011
# differential_evolution step 391: f(x)= 107.89237461296011
# differential_evolution step 392: f(x)= 107.89237461296011
# differential_evolution step 393: f(x)= 107.89237461296011
# differential_evolution step 394: f(x)= 107.89237461296011
# differential_evolution step 395: f(x)= 107.89237461296011
# differential_evolution step 396: f(x)= 107.89237461296011
# differential_evolution step 397: f(x)= 107.89237461296011
# differential_evolution step 398: f(x)= 107.89237461296011
# differential_evolution step 399: f(x)= 107.85409888590316
# differential_evolution step 400: f(x)= 107.85409888590316
# differential_evolution step 401: f(x)= 107.85409888590316
# differential_evolution step 402: f(x)= 107.85409888590316
# differential_evolution step 403: f(x)= 107.85409888590316
# differential_evolution step 404: f(x)= 107.85409888590316
# differential_evolution step 405: f(x)= 107.85409888590316
# differential_evolution step 406: f(x)= 107.85409888590316
# differential_evolution step 407: f(x)= 107.85409888590316
# differential_evolution step 408: f(x)= 107.85409888590316
# differential_evolution step 409: f(x)= 107.85409888590316
# differential_evolution step 410: f(x)= 107.85409888590316
# differential_evolution step 411: f(x)= 107.85409888590316
# differential_evolution step 412: f(x)= 107.85409888590316
# differential_evolution step 413: f(x)= 107.85409888590316
# differential_evolution step 414: f(x)= 107.85409888590316
# differential_evolution step 415: f(x)= 107.85409888590316
# differential_evolution step 416: f(x)= 107.85409888590316
# differential_evolution step 417: f(x)= 107.85409888590316
# differential_evolution step 418: f(x)= 107.78333556960112
# differential_evolution step 419: f(x)= 107.78333556960112
# differential_evolution step 420: f(x)= 107.78333556960112
# differential_evolution step 421: f(x)= 107.7737411748204
# differential_evolution step 422: f(x)= 107.7737411748204
# differential_evolution step 423: f(x)= 107.7737411748204
# differential_evolution step 424: f(x)= 107.7737411748204
# differential_evolution step 425: f(x)= 107.7737411748204
# differential_evolution step 426: f(x)= 107.7737411748204
# differential_evolution step 427: f(x)= 107.7737411748204
# differential_evolution step 428: f(x)= 107.7737411748204
# differential_evolution step 429: f(x)= 107.7737411748204
# differential_evolution step 430: f(x)= 107.7737411748204
# differential_evolution step 431: f(x)= 107.7737411748204
# differential_evolution step 432: f(x)= 107.7737411748204
# differential_evolution step 433: f(x)= 107.7737411748204
# differential_evolution step 434: f(x)= 107.71909750188341
# differential_evolution step 435: f(x)= 107.71909750188341
# differential_evolution step 436: f(x)= 107.71909750188341
# differential_evolution step 437: f(x)= 107.71909750188341
# differential_evolution step 438: f(x)= 107.71909750188341
# differential_evolution step 439: f(x)= 107.64777847370117
# differential_evolution step 440: f(x)= 107.64777847370117
# differential_evolution step 441: f(x)= 107.64777847370117
# differential_evolution step 442: f(x)= 107.64777847370117
# differential_evolution step 443: f(x)= 107.64777847370117
# differential_evolution step 444: f(x)= 107.64777847370117
# differential_evolution step 445: f(x)= 107.64777847370117
# differential_evolution step 446: f(x)= 107.61662060606444
# differential_evolution step 447: f(x)= 107.61662060606444
# differential_evolution step 448: f(x)= 107.57287090193485
# differential_evolution step 449: f(x)= 107.57287090193485
# differential_evolution step 450: f(x)= 107.49764770924341
# differential_evolution step 451: f(x)= 107.49764770924341
# differential_evolution step 452: f(x)= 107.49764770924341
# differential_evolution step 453: f(x)= 107.49764770924341
# differential_evolution step 454: f(x)= 107.49764770924341
# differential_evolution step 455: f(x)= 107.49764770924341
# differential_evolution step 456: f(x)= 107.49764770924341
# differential_evolution step 457: f(x)= 107.38677650463522
# differential_evolution step 458: f(x)= 107.38677650463522
# differential_evolution step 459: f(x)= 107.38677650463522
# differential_evolution step 460: f(x)= 107.38677650463522
# differential_evolution step 461: f(x)= 107.3762707305364
# differential_evolution step 462: f(x)= 107.31704136252984
# differential_evolution step 463: f(x)= 107.31704136252984
# differential_evolution step 464: f(x)= 107.31704136252984
# differential_evolution step 465: f(x)= 107.31704136252984
# differential_evolution step 466: f(x)= 107.31704136252984
# differential_evolution step 467: f(x)= 107.31704136252984
# differential_evolution step 468: f(x)= 107.31704136252984
# differential_evolution step 469: f(x)= 107.31704136252984
# differential_evolution step 470: f(x)= 107.31704136252984
# differential_evolution step 471: f(x)= 107.31704136252984
# differential_evolution step 472: f(x)= 107.31704136252984
# differential_evolution step 473: f(x)= 107.31704136252984
# differential_evolution step 474: f(x)= 107.31704136252984
# differential_evolution step 475: f(x)= 107.31704136252984
# differential_evolution step 476: f(x)= 107.31704136252984
# differential_evolution step 477: f(x)= 107.31704136252984
# differential_evolution step 478: f(x)= 107.31704136252984
# differential_evolution step 479: f(x)= 107.31704136252984
# differential_evolution step 480: f(x)= 107.25016531610213
# differential_evolution step 481: f(x)= 107.23031165798804
# differential_evolution step 482: f(x)= 107.23031165798804
# differential_evolution step 483: f(x)= 107.23031165798804
# differential_evolution step 484: f(x)= 107.23031165798804
# differential_evolution step 485: f(x)= 107.23031165798804
# differential_evolution step 486: f(x)= 107.18626287314216
# differential_evolution step 487: f(x)= 107.18626287314216
# differential_evolution step 488: f(x)= 107.18626287314216
# differential_evolution step 489: f(x)= 107.18626287314216
# differential_evolution step 490: f(x)= 107.18626287314216
# differential_evolution step 491: f(x)= 107.16324852100044
# differential_evolution step 492: f(x)= 107.16324852100044
# differential_evolution step 493: f(x)= 107.16324852100044
# differential_evolution step 494: f(x)= 107.16324852100044
# differential_evolution step 495: f(x)= 107.16324852100044
# differential_evolution step 496: f(x)= 107.16324852100044
# differential_evolution step 497: f(x)= 107.07678593251035
# differential_evolution step 498: f(x)= 107.07678593251035
# differential_evolution step 499: f(x)= 107.07678593251035
# differential_evolution step 500: f(x)= 107.07678593251035
# differential_evolution step 501: f(x)= 106.99467138262986
# differential_evolution step 502: f(x)= 106.91729264583657
# differential_evolution step 503: f(x)= 106.91729264583657
# differential_evolution step 504: f(x)= 106.91729264583657
# differential_evolution step 505: f(x)= 106.87698116865703
# differential_evolution step 506: f(x)= 106.87698116865703
# differential_evolution step 507: f(x)= 106.87698116865703
# differential_evolution step 508: f(x)= 106.87698116865703
# differential_evolution step 509: f(x)= 106.87698116865703
# differential_evolution step 510: f(x)= 106.87698116865703
# differential_evolution step 511: f(x)= 106.87698116865703
# differential_evolution step 512: f(x)= 106.86582788380893
# differential_evolution step 513: f(x)= 106.86582788380893
# differential_evolution step 514: f(x)= 106.74783807933298
# differential_evolution step 515: f(x)= 106.70545349067262
# differential_evolution step 516: f(x)= 106.70545349067262
# differential_evolution step 517: f(x)= 106.6900278310773
# differential_evolution step 518: f(x)= 106.6019741558631
# differential_evolution step 519: f(x)= 106.6019741558631
# differential_evolution step 520: f(x)= 106.44914594562619
# differential_evolution step 521: f(x)= 106.33611331986835
# differential_evolution step 522: f(x)= 106.29548918940165
# differential_evolution step 523: f(x)= 106.29548918940165
# differential_evolution step 524: f(x)= 106.29548918940165
# differential_evolution step 525: f(x)= 105.97099280477772
# differential_evolution step 526: f(x)= 105.95008119855585
# differential_evolution step 527: f(x)= 105.85407257330334
# differential_evolution step 528: f(x)= 105.5792954892008
# differential_evolution step 529: f(x)= 105.30171582674906
# differential_evolution step 530: f(x)= 105.2515380444014
# differential_evolution step 531: f(x)= 105.2515380444014
# differential_evolution step 532: f(x)= 105.2515380444014
# differential_evolution step 533: f(x)= 104.90571682046894
# differential_evolution step 534: f(x)= 104.87547397462329
# differential_evolution step 535: f(x)= 104.87547397462329
# differential_evolution step 536: f(x)= 104.69374419730617
# differential_evolution step 537: f(x)= 104.69374419730617
# differential_evolution step 538: f(x)= 104.69374419730617
# differential_evolution step 539: f(x)= 104.69374419730617
# differential_evolution step 540: f(x)= 104.63990741348134
# differential_evolution step 541: f(x)= 104.63990741348134
# differential_evolution step 542: f(x)= 104.63990741348134
# differential_evolution step 543: f(x)= 104.63990741348134
# differential_evolution step 544: f(x)= 104.63990741348134
# differential_evolution step 545: f(x)= 104.40688473933176
# differential_evolution step 546: f(x)= 104.40688473933176
# differential_evolution step 547: f(x)= 104.40688473933176
# differential_evolution step 548: f(x)= 104.40688473933176
# differential_evolution step 549: f(x)= 104.40688473933176
# differential_evolution step 550: f(x)= 104.12080686679012
# differential_evolution step 551: f(x)= 104.12080686679012
# differential_evolution step 552: f(x)= 104.12080686679012
# differential_evolution step 553: f(x)= 103.88694702257501
# differential_evolution step 554: f(x)= 103.75727391741499
# differential_evolution step 555: f(x)= 103.75727391741499
# differential_evolution step 556: f(x)= 103.75727391741499
# differential_evolution step 557: f(x)= 103.54351784113474
# differential_evolution step 558: f(x)= 103.25419511476755
# differential_evolution step 559: f(x)= 103.25419511476755
# differential_evolution step 560: f(x)= 103.25419511476755
# differential_evolution step 561: f(x)= 103.25419511476755
# differential_evolution step 562: f(x)= 103.17834742180976
# differential_evolution step 563: f(x)= 103.17834742180976
# differential_evolution step 564: f(x)= 103.17834742180976
# differential_evolution step 565: f(x)= 103.17834742180976
# differential_evolution step 566: f(x)= 103.17834742180976
# differential_evolution step 567: f(x)= 103.17834742180976
# differential_evolution step 568: f(x)= 103.17834742180976
# differential_evolution step 569: f(x)= 103.17834742180976
# differential_evolution step 570: f(x)= 102.9094387682487
# differential_evolution step 571: f(x)= 102.43707023556858
# differential_evolution step 572: f(x)= 102.36052742539552
# differential_evolution step 573: f(x)= 102.36052742539552
# differential_evolution step 574: f(x)= 102.36052742539552
# differential_evolution step 575: f(x)= 102.36052742539552
# differential_evolution step 576: f(x)= 102.36052742539552
# differential_evolution step 577: f(x)= 102.36052742539552
# differential_evolution step 578: f(x)= 102.34009191041467
# differential_evolution step 579: f(x)= 102.32455704568159
# differential_evolution step 580: f(x)= 102.32455704568159
# differential_evolution step 581: f(x)= 102.15936887771784
# differential_evolution step 582: f(x)= 101.9025672182123
# differential_evolution step 583: f(x)= 101.9025672182123
# differential_evolution step 584: f(x)= 101.75403295161424
# differential_evolution step 585: f(x)= 101.55756390965836
# differential_evolution step 586: f(x)= 101.0093574622903
# differential_evolution step 587: f(x)= 101.0093574622903
# differential_evolution step 588: f(x)= 101.0093574622903
# differential_evolution step 589: f(x)= 101.0093574622903
# differential_evolution step 590: f(x)= 100.91372784352814
# differential_evolution step 591: f(x)= 100.91372784352814
# differential_evolution step 592: f(x)= 100.8536772416866
# differential_evolution step 593: f(x)= 100.8536772416866
# differential_evolution step 594: f(x)= 98.45010504509224
# differential_evolution step 595: f(x)= 98.45010504509224
# differential_evolution step 596: f(x)= 98.45010504509224
# differential_evolution step 597: f(x)= 98.36251530631935
# differential_evolution step 598: f(x)= 98.36251530631935
# differential_evolution step 599: f(x)= 98.36251530631935
# differential_evolution step 600: f(x)= 97.97772586227552
# differential_evolution step 601: f(x)= 97.22417262460185
# differential_evolution step 602: f(x)= 97.22417262460185
# differential_evolution step 603: f(x)= 97.22417262460185
# differential_evolution step 604: f(x)= 97.22417262460185
# differential_evolution step 605: f(x)= 97.22417262460185
# differential_evolution step 606: f(x)= 97.22417262460185
# differential_evolution step 607: f(x)= 97.22417262460185
# differential_evolution step 608: f(x)= 97.22417262460185
# differential_evolution step 609: f(x)= 97.22417262460185
# differential_evolution step 610: f(x)= 97.22417262460185
# differential_evolution step 611: f(x)= 97.22417262460185
# differential_evolution step 612: f(x)= 97.22417262460185
# differential_evolution step 613: f(x)= 97.22417262460185
# differential_evolution step 614: f(x)= 97.22417262460185
# differential_evolution step 615: f(x)= 97.22417262460185
# differential_evolution step 616: f(x)= 97.22417262460185
# differential_evolution step 617: f(x)= 97.09212301342129
# differential_evolution step 618: f(x)= 96.76083452292538
# differential_evolution step 619: f(x)= 96.61737681333669
# differential_evolution step 620: f(x)= 96.21133775379
# differential_evolution step 621: f(x)= 95.32517570676023
# differential_evolution step 622: f(x)= 95.32517570676023
# differential_evolution step 623: f(x)= 95.26823918346162
# differential_evolution step 624: f(x)= 95.26823918346162
# differential_evolution step 625: f(x)= 95.26823918346162
# differential_evolution step 626: f(x)= 95.26823918346162
# differential_evolution step 627: f(x)= 95.26823918346162
# differential_evolution step 628: f(x)= 93.79220422932383
# differential_evolution step 629: f(x)= 93.79220422932383
# differential_evolution step 630: f(x)= 93.79220422932383
# differential_evolution step 631: f(x)= 93.60120659080384
# differential_evolution step 632: f(x)= 92.62282328422614
# differential_evolution step 633: f(x)= 92.62282328422614
# differential_evolution step 634: f(x)= 92.62282328422614
# differential_evolution step 635: f(x)= 92.62282328422614
# differential_evolution step 636: f(x)= 92.62282328422614
# differential_evolution step 637: f(x)= 92.41606101500098
# differential_evolution step 638: f(x)= 92.41606101500098
# differential_evolution step 639: f(x)= 92.41606101500098
# differential_evolution step 640: f(x)= 92.27758357236583
# differential_evolution step 641: f(x)= 92.27758357236583
# differential_evolution step 642: f(x)= 92.27758357236583
# differential_evolution step 643: f(x)= 92.20837458126607
# differential_evolution step 644: f(x)= 92.20837458126607
# differential_evolution step 645: f(x)= 92.20837458126607
# differential_evolution step 646: f(x)= 92.20837458126607
# differential_evolution step 647: f(x)= 92.01203859306152
# differential_evolution step 648: f(x)= 91.18152134794504
# differential_evolution step 649: f(x)= 91.00775381567067
# differential_evolution step 650: f(x)= 90.47643083908284
# differential_evolution step 651: f(x)= 90.47643083908284
# differential_evolution step 652: f(x)= 90.47643083908284
# differential_evolution step 653: f(x)= 90.42181675030685
# differential_evolution step 654: f(x)= 90.42181675030685
# differential_evolution step 655: f(x)= 90.42181675030685
# differential_evolution step 656: f(x)= 90.41728621518415
# differential_evolution step 657: f(x)= 90.41728621518415
# differential_evolution step 658: f(x)= 90.41728621518415
# differential_evolution step 659: f(x)= 90.41728621518415
# differential_evolution step 660: f(x)= 90.41728621518415
# differential_evolution step 661: f(x)= 89.72810605485792
# differential_evolution step 662: f(x)= 89.72810605485792
# differential_evolution step 663: f(x)= 89.72810605485792
# differential_evolution step 664: f(x)= 89.72810605485792
# differential_evolution step 665: f(x)= 89.42360804168928
# differential_evolution step 666: f(x)= 89.42360804168928
# differential_evolution step 667: f(x)= 89.42360804168928
# differential_evolution step 668: f(x)= 89.42360804168928
# differential_evolution step 669: f(x)= 89.42360804168928
# differential_evolution step 670: f(x)= 89.42360804168928
# differential_evolution step 671: f(x)= 89.42360804168928
# differential_evolution step 672: f(x)= 89.42360804168928
# differential_evolution step 673: f(x)= 89.42360804168928
# differential_evolution step 674: f(x)= 89.2593858462774
# differential_evolution step 675: f(x)= 88.5201979698206
# differential_evolution step 676: f(x)= 88.5201979698206
# differential_evolution step 677: f(x)= 88.5201979698206
# differential_evolution step 678: f(x)= 88.5201979698206
# differential_evolution step 679: f(x)= 88.41317859224185
# differential_evolution step 680: f(x)= 88.41317859224185
# differential_evolution step 681: f(x)= 88.41317859224185
# differential_evolution step 682: f(x)= 88.41317859224185
# differential_evolution step 683: f(x)= 88.41317859224185
# differential_evolution step 684: f(x)= 88.41317859224185
# differential_evolution step 685: f(x)= 88.41317859224185
# differential_evolution step 686: f(x)= 88.41317859224185
# differential_evolution step 687: f(x)= 87.89725901348251
# differential_evolution step 688: f(x)= 87.89725901348251
# differential_evolution step 689: f(x)= 87.89725901348251
# differential_evolution step 690: f(x)= 87.89725901348251
# differential_evolution step 691: f(x)= 87.89725901348251
# differential_evolution step 692: f(x)= 87.89725901348251
# differential_evolution step 693: f(x)= 87.89725901348251
# differential_evolution step 694: f(x)= 87.89725901348251
# differential_evolution step 695: f(x)= 87.89725901348251
# differential_evolution step 696: f(x)= 87.89725901348251
# differential_evolution step 697: f(x)= 87.89725901348251
# differential_evolution step 698: f(x)= 87.89725901348251
# differential_evolution step 699: f(x)= 87.89725901348251
# differential_evolution step 700: f(x)= 87.89725901348251
# differential_evolution step 701: f(x)= 87.89725901348251
# differential_evolution step 702: f(x)= 87.89318364472724
# differential_evolution step 703: f(x)= 87.89318364472724
# differential_evolution step 704: f(x)= 87.67122930973646
# differential_evolution step 705: f(x)= 87.6193529668771
# differential_evolution step 706: f(x)= 87.6193529668771
# differential_evolution step 707: f(x)= 87.6193529668771
# differential_evolution step 708: f(x)= 87.6178193122969
# differential_evolution step 709: f(x)= 87.6178193122969
# differential_evolution step 710: f(x)= 87.6178193122969
# differential_evolution step 711: f(x)= 87.6178193122969
# differential_evolution step 712: f(x)= 87.6178193122969
# differential_evolution step 713: f(x)= 87.6178193122969
# differential_evolution step 714: f(x)= 87.6178193122969
# differential_evolution step 715: f(x)= 87.6178193122969
# differential_evolution step 716: f(x)= 87.55893579185897
# differential_evolution step 717: f(x)= 87.55893579185897
# differential_evolution step 718: f(x)= 87.55893579185897
# differential_evolution step 719: f(x)= 87.46587517245064
# differential_evolution step 720: f(x)= 87.46587517245064
# differential_evolution step 721: f(x)= 87.46587517245064
# differential_evolution step 722: f(x)= 87.46587517245064
# differential_evolution step 723: f(x)= 87.46587517245064
# differential_evolution step 724: f(x)= 87.42056018271542
# differential_evolution step 725: f(x)= 87.42056018271542
# differential_evolution step 726: f(x)= 87.42056018271542
# differential_evolution step 727: f(x)= 87.42056018271542
# differential_evolution step 728: f(x)= 87.23287641466513
# differential_evolution step 729: f(x)= 87.23287641466513
# differential_evolution step 730: f(x)= 87.23287641466513
# differential_evolution step 731: f(x)= 87.23287641466513
# differential_evolution step 732: f(x)= 87.23287641466513
# differential_evolution step 733: f(x)= 87.23287641466513
# differential_evolution step 734: f(x)= 87.23287641466513
# differential_evolution step 735: f(x)= 87.23287641466513
# differential_evolution step 736: f(x)= 87.23287641466513
# differential_evolution step 737: f(x)= 87.23287641466513
# differential_evolution step 738: f(x)= 87.23287641466513
# differential_evolution step 739: f(x)= 87.23287641466513
# differential_evolution step 740: f(x)= 87.23287641466513
# differential_evolution step 741: f(x)= 87.23287641466513
# differential_evolution step 742: f(x)= 87.23287641466513
# differential_evolution step 743: f(x)= 87.23287641466513
# differential_evolution step 744: f(x)= 87.23287641466513
# differential_evolution step 745: f(x)= 87.23287641466513
# differential_evolution step 746: f(x)= 87.23287641466513
# differential_evolution step 747: f(x)= 87.23287641466513
# differential_evolution step 748: f(x)= 87.23287641466513
# differential_evolution step 749: f(x)= 87.23287641466513
# differential_evolution step 750: f(x)= 87.23287641466513
# differential_evolution step 751: f(x)= 87.21739878970209
# differential_evolution step 752: f(x)= 87.21739878970209
# differential_evolution step 753: f(x)= 87.21739878970209
# differential_evolution step 754: f(x)= 87.07805047581533
# differential_evolution step 755: f(x)= 87.07805047581533
# differential_evolution step 756: f(x)= 87.07805047581533
# differential_evolution step 757: f(x)= 87.07805047581533
# differential_evolution step 758: f(x)= 87.07805047581533
# differential_evolution step 759: f(x)= 87.07805047581533
# differential_evolution step 760: f(x)= 87.07805047581533
# differential_evolution step 761: f(x)= 87.07805047581533
# differential_evolution step 762: f(x)= 87.07805047581533
# differential_evolution step 763: f(x)= 87.07805047581533
# differential_evolution step 764: f(x)= 87.07805047581533
# differential_evolution step 765: f(x)= 87.07805047581533
# differential_evolution step 766: f(x)= 87.07805047581533
# differential_evolution step 767: f(x)= 87.07805047581533
# differential_evolution step 768: f(x)= 87.07805047581533
# differential_evolution step 769: f(x)= 87.07805047581533
# differential_evolution step 770: f(x)= 87.07805047581533
# differential_evolution step 771: f(x)= 87.07805047581533
# differential_evolution step 772: f(x)= 87.07805047581533
# differential_evolution step 773: f(x)= 87.07805047581533
# differential_evolution step 774: f(x)= 87.07805047581533
# differential_evolution step 775: f(x)= 87.07805047581533
# differential_evolution step 776: f(x)= 87.07805047581533
# differential_evolution step 777: f(x)= 87.07805047581533
# differential_evolution step 778: f(x)= 87.07805047581533
# differential_evolution step 779: f(x)= 87.07805047581533
# differential_evolution step 780: f(x)= 87.07805047581533
# differential_evolution step 781: f(x)= 87.07395173394852
# differential_evolution step 782: f(x)= 87.07395173394852
# differential_evolution step 783: f(x)= 87.07395173394852
# differential_evolution step 784: f(x)= 87.07395173394852
# differential_evolution step 785: f(x)= 87.07395173394852
# differential_evolution step 786: f(x)= 87.07395173394852
# differential_evolution step 787: f(x)= 87.07395173394852
# differential_evolution step 788: f(x)= 87.07395173394852
# differential_evolution step 789: f(x)= 87.07395173394852
# differential_evolution step 790: f(x)= 87.07395173394852
# differential_evolution step 791: f(x)= 87.07395173394852
# differential_evolution step 792: f(x)= 87.07395173394852
# differential_evolution step 793: f(x)= 87.07395173394852
# differential_evolution step 794: f(x)= 87.07395173394852
# differential_evolution step 795: f(x)= 87.07395173394852
# differential_evolution step 796: f(x)= 87.07395173394852
# differential_evolution step 797: f(x)= 87.06343622161587
# differential_evolution step 798: f(x)= 87.06343622161587
# differential_evolution step 799: f(x)= 87.06343622161587
# differential_evolution step 800: f(x)= 87.06343622161587
# differential_evolution step 801: f(x)= 87.06343622161587
# differential_evolution step 802: f(x)= 87.06343622161587
# differential_evolution step 803: f(x)= 87.06343622161587
# differential_evolution step 804: f(x)= 87.06343622161587
# differential_evolution step 805: f(x)= 87.06343622161587
# differential_evolution step 806: f(x)= 87.06343622161587
# differential_evolution step 807: f(x)= 87.06343622161587
# differential_evolution step 808: f(x)= 87.06343622161587
# differential_evolution step 809: f(x)= 87.06343622161587
# differential_evolution step 810: f(x)= 87.06343622161587
# differential_evolution step 811: f(x)= 87.06343622161587
# differential_evolution step 812: f(x)= 87.06343622161587
# differential_evolution step 813: f(x)= 87.05757831712094
# differential_evolution step 814: f(x)= 87.05757831712094
# differential_evolution step 815: f(x)= 87.05757831712094
# differential_evolution step 816: f(x)= 87.05757831712094
# differential_evolution step 817: f(x)= 87.05757831712094
# differential_evolution step 818: f(x)= 87.05757831712094
# differential_evolution step 819: f(x)= 87.05757831712094
# differential_evolution step 820: f(x)= 87.05757831712094
# differential_evolution step 821: f(x)= 87.05757831712094
# differential_evolution step 822: f(x)= 87.05757831712094
# differential_evolution step 823: f(x)= 87.05757831712094
# differential_evolution step 824: f(x)= 87.05757831712094
# differential_evolution step 825: f(x)= 87.05757831712094
# differential_evolution step 826: f(x)= 87.05757831712094
# differential_evolution step 827: f(x)= 87.05757831712094
# differential_evolution step 828: f(x)= 87.05757831712094
# differential_evolution step 829: f(x)= 87.05757831712094
# differential_evolution step 830: f(x)= 87.05757831712094
# differential_evolution step 831: f(x)= 87.05757831712094
# differential_evolution step 832: f(x)= 87.05757831712094
# differential_evolution step 833: f(x)= 87.05757831712094
# differential_evolution step 834: f(x)= 87.05757831712094
# differential_evolution step 835: f(x)= 87.05757831712094
# differential_evolution step 836: f(x)= 87.0488583538233
# differential_evolution step 837: f(x)= 87.0488583538233
# differential_evolution step 838: f(x)= 87.0488583538233
# differential_evolution step 839: f(x)= 87.0488583538233
# differential_evolution step 840: f(x)= 87.0488583538233
# differential_evolution step 841: f(x)= 87.0488583538233
# differential_evolution step 842: f(x)= 87.0488583538233
# differential_evolution step 843: f(x)= 87.0488583538233
# differential_evolution step 844: f(x)= 87.0488583538233
# differential_evolution step 845: f(x)= 87.0488583538233
# differential_evolution step 846: f(x)= 87.0488583538233
# differential_evolution step 847: f(x)= 87.0488583538233
# differential_evolution step 848: f(x)= 87.0488583538233
# differential_evolution step 849: f(x)= 87.0488583538233
# differential_evolution step 850: f(x)= 87.0488583538233
# differential_evolution step 851: f(x)= 87.04263383338512
# differential_evolution step 852: f(x)= 87.04263383338512
# differential_evolution step 853: f(x)= 87.04263383338512
# differential_evolution step 854: f(x)= 87.04263383338512
# differential_evolution step 855: f(x)= 87.04263383338512
# differential_evolution step 856: f(x)= 87.04263383338512
# differential_evolution step 857: f(x)= 87.04263383338512
# differential_evolution step 858: f(x)= 87.04263383338512
# differential_evolution step 859: f(x)= 87.04263383338512
# differential_evolution step 860: f(x)= 87.04263383338512
# differential_evolution step 861: f(x)= 87.04263383338512
# differential_evolution step 862: f(x)= 87.04263383338512
# differential_evolution step 863: f(x)= 87.04263383338512
# differential_evolution step 864: f(x)= 87.04263383338512
# differential_evolution step 865: f(x)= 87.04263383338512
# differential_evolution step 866: f(x)= 87.04263383338512
# differential_evolution step 867: f(x)= 87.04263383338512
# differential_evolution step 868: f(x)= 87.04263383338512
# differential_evolution step 869: f(x)= 87.04263383338512
# differential_evolution step 870: f(x)= 87.04263383338512
# differential_evolution step 871: f(x)= 87.03850545447011
# differential_evolution step 872: f(x)= 87.03850545447011
# differential_evolution step 873: f(x)= 87.03850545447011
# differential_evolution step 874: f(x)= 87.03850545447011
# differential_evolution step 875: f(x)= 87.03850545447011
# differential_evolution step 876: f(x)= 87.03850545447011
# differential_evolution step 877: f(x)= 87.03850545447011
# differential_evolution step 878: f(x)= 87.03850545447011
# differential_evolution step 879: f(x)= 87.03850545447011
# differential_evolution step 880: f(x)= 87.03669318996461
# differential_evolution step 881: f(x)= 87.03669318996461
# differential_evolution step 882: f(x)= 87.03669318996461
# differential_evolution step 883: f(x)= 87.03669318996461
# differential_evolution step 884: f(x)= 87.03669318996461
# differential_evolution step 885: f(x)= 87.03548839378074
# differential_evolution step 886: f(x)= 87.03548839378074
# differential_evolution step 887: f(x)= 87.03548839378074
# differential_evolution step 888: f(x)= 87.03548839378074
# differential_evolution step 889: f(x)= 87.03548839378074
# differential_evolution step 890: f(x)= 87.03548839378074
# differential_evolution step 891: f(x)= 87.03548839378074
# differential_evolution step 892: f(x)= 87.03547548073146
# differential_evolution step 893: f(x)= 87.03547548073146
# differential_evolution step 894: f(x)= 87.03547548073146
# differential_evolution step 895: f(x)= 87.03547548073146
# differential_evolution step 896: f(x)= 87.03547548073146
# differential_evolution step 897: f(x)= 87.03547548073146
# differential_evolution step 898: f(x)= 87.03547548073146
# differential_evolution step 899: f(x)= 87.03547548073146
# differential_evolution step 900: f(x)= 87.03547548073146
# differential_evolution step 901: f(x)= 87.03547548073146
# differential_evolution step 902: f(x)= 87.03547548073146
# differential_evolution step 903: f(x)= 87.03547548073146
# differential_evolution step 904: f(x)= 87.03547548073146
# differential_evolution step 905: f(x)= 87.03547548073146
# differential_evolution step 906: f(x)= 87.03158825455706
# differential_evolution step 907: f(x)= 87.03158825455706
# differential_evolution step 908: f(x)= 87.03158825455706
# differential_evolution step 909: f(x)= 87.03158825455706
# differential_evolution step 910: f(x)= 87.03158825455706
# differential_evolution step 911: f(x)= 87.03158825455706
# differential_evolution step 912: f(x)= 87.03158825455706
# differential_evolution step 913: f(x)= 87.03158825455706
# differential_evolution step 914: f(x)= 87.03158825455706
# differential_evolution step 915: f(x)= 87.03158825455706
# differential_evolution step 916: f(x)= 87.03158825455706
# differential_evolution step 917: f(x)= 87.03158825455706
# differential_evolution step 918: f(x)= 87.03158825455706
# differential_evolution step 919: f(x)= 87.03158825455706
# differential_evolution step 920: f(x)= 87.03158825455706
# differential_evolution step 921: f(x)= 87.03158825455706
# differential_evolution step 922: f(x)= 87.03158825455706
# differential_evolution step 923: f(x)= 87.03158825455706
# differential_evolution step 924: f(x)= 87.03158825455706
# differential_evolution step 925: f(x)= 87.03158825455706
# differential_evolution step 926: f(x)= 87.03158825455706
# differential_evolution step 927: f(x)= 87.03158825455706
# differential_evolution step 928: f(x)= 87.03158825455706
# differential_evolution step 929: f(x)= 87.03158825455706
# differential_evolution step 930: f(x)= 87.03158825455706
# differential_evolution step 931: f(x)= 87.03158825455706
# differential_evolution step 932: f(x)= 87.03158825455706
# differential_evolution step 933: f(x)= 87.03158825455706
# differential_evolution step 934: f(x)= 87.03158825455706
# differential_evolution step 935: f(x)= 87.03137232840524
# differential_evolution step 936: f(x)= 87.03120894174774
# differential_evolution step 937: f(x)= 87.03120894174774
# differential_evolution step 938: f(x)= 87.03016899796357
# differential_evolution step 939: f(x)= 87.03016899796357
# differential_evolution step 940: f(x)= 87.0297493490711
# differential_evolution step 941: f(x)= 87.0297493490711
# differential_evolution step 942: f(x)= 87.0297493490711
# differential_evolution step 943: f(x)= 87.0297493490711
# differential_evolution step 944: f(x)= 87.0297493490711
# differential_evolution step 945: f(x)= 87.0297493490711
# differential_evolution step 946: f(x)= 87.0297493490711
# differential_evolution step 947: f(x)= 87.0297493490711
# differential_evolution step 948: f(x)= 87.0297493490711
# differential_evolution step 949: f(x)= 87.0297493490711
# differential_evolution step 950: f(x)= 87.0297493490711
# differential_evolution step 951: f(x)= 87.0297493490711
# differential_evolution step 952: f(x)= 87.0297493490711
# differential_evolution step 953: f(x)= 87.0297493490711
# differential_evolution step 954: f(x)= 87.02966088465715
# differential_evolution step 955: f(x)= 87.02966088465715
# differential_evolution step 956: f(x)= 87.02961423218873
# differential_evolution step 957: f(x)= 87.02961423218873
# differential_evolution step 958: f(x)= 87.02961423218873
# differential_evolution step 959: f(x)= 87.02961423218873
# differential_evolution step 960: f(x)= 87.02961423218873
# differential_evolution step 961: f(x)= 87.02874374872981
# differential_evolution step 962: f(x)= 87.02874374872981
# differential_evolution step 963: f(x)= 87.02874374872981
# differential_evolution step 964: f(x)= 87.02874374872981
# differential_evolution step 965: f(x)= 87.02874374872981
# differential_evolution step 966: f(x)= 87.02874374872981
# differential_evolution step 967: f(x)= 87.02874374872981
# differential_evolution step 968: f(x)= 87.02874374872981
# differential_evolution step 969: f(x)= 87.02874374872981
# differential_evolution step 970: f(x)= 87.02874374872981
# differential_evolution step 971: f(x)= 87.02874374872981
# differential_evolution step 972: f(x)= 87.02874374872981
# differential_evolution step 973: f(x)= 87.02874374872981
# differential_evolution step 974: f(x)= 87.02874374872981
# differential_evolution step 975: f(x)= 87.02874374872981
# differential_evolution step 976: f(x)= 87.02874374872981
# differential_evolution step 977: f(x)= 87.02874374872981
# differential_evolution step 978: f(x)= 87.02874374872981
# differential_evolution step 979: f(x)= 87.02874374872981
# differential_evolution step 980: f(x)= 87.02874374872981
# differential_evolution step 981: f(x)= 87.02874374872981
# differential_evolution step 982: f(x)= 87.02874374872981
# differential_evolution step 983: f(x)= 87.02874374872981
# differential_evolution step 984: f(x)= 87.02874374872981
# differential_evolution step 985: f(x)= 87.02874374872981
# differential_evolution step 986: f(x)= 87.02874374872981
# differential_evolution step 987: f(x)= 87.02874374872981
# differential_evolution step 988: f(x)= 87.02874374872981
# differential_evolution step 989: f(x)= 87.02874374872981
# differential_evolution step 990: f(x)= 87.02874374872981
# differential_evolution step 991: f(x)= 87.02874374872981
# differential_evolution step 992: f(x)= 87.02874374872981
# differential_evolution step 993: f(x)= 87.02874374872981
# differential_evolution step 994: f(x)= 87.02874374872981
# differential_evolution step 995: f(x)= 87.02874374872981
# differential_evolution step 996: f(x)= 87.02874374872981
# differential_evolution step 997: f(x)= 87.02874374872981
# differential_evolution step 998: f(x)= 87.02874374872981
# differential_evolution step 999: f(x)= 87.02874374872981
# differential_evolution step 1000: f(x)= 87.02874374872981
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.6939, r_e=17.5450, n=1.3356, x_0=45.0000
# Sérsic 2: I_e=18.0691, r_e=1.8801, n=0.5336, x_0=51.4596
# Sérsic 3: I_e=17.2635, r_e=5.1748, n=0.8092, x_0=60.7122
# Chi quadro minimo: 87.02850512919642
# False

# %%
plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, sigma = radial_profile_error_HA, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, radial_profile_error_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.4847, r_e=18.3500, n=1.3895, x_0=45.0000
# Sérsic 2: I_e=14.9750, r_e=2.0894, n=0.6491, x_0=51.4045
# Sérsic 3: I_e=14.7407, r_e=5.6714, n=0.9108, x_0=60.7384
# [0.19953405 1.15982788 0.08803729 0.36420144 4.29587825 0.35561403
#  0.21835794 0.07389992 0.70533642 0.14280402 0.03575844 0.06797577]
# 133.1589746633708

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.2, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.2, x_0_HA[1]+1.2),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2)
]

# %%
bounds
# Out:
# [(0, 10),
#  (0, 50),
#  (0.1, 10),
#  (43.8, 46.2),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (50.204499999999996, 52.6045),
#  (0, 10),
#  (0, 50),
#  (0.1, 10),
#  (59.538399999999996, 61.9384)]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2194.446603205664
# differential_evolution step 2: f(x)= 1299.2288446382688
# differential_evolution step 3: f(x)= 898.256464907712
# differential_evolution step 4: f(x)= 756.5149167122406
# differential_evolution step 5: f(x)= 756.5149167122406
# differential_evolution step 6: f(x)= 756.5149167122406
# differential_evolution step 7: f(x)= 756.5149167122406
# differential_evolution step 8: f(x)= 379.50529734834475
# differential_evolution step 9: f(x)= 379.50529734834475
# differential_evolution step 10: f(x)= 266.21801246633476
# differential_evolution step 11: f(x)= 266.21801246633476
# differential_evolution step 12: f(x)= 266.21801246633476
# differential_evolution step 13: f(x)= 266.21801246633476
# differential_evolution step 14: f(x)= 266.21801246633476
# differential_evolution step 15: f(x)= 247.26613080054406
# differential_evolution step 16: f(x)= 247.26613080054406
# differential_evolution step 17: f(x)= 223.31212984313103
# differential_evolution step 18: f(x)= 126.22268636795532
# differential_evolution step 19: f(x)= 126.22268636795532
# differential_evolution step 20: f(x)= 126.22268636795532
# differential_evolution step 21: f(x)= 126.22268636795532
# differential_evolution step 22: f(x)= 126.22268636795532
# differential_evolution step 23: f(x)= 126.22268636795532
# differential_evolution step 24: f(x)= 126.22268636795532
# differential_evolution step 25: f(x)= 126.22268636795532
# differential_evolution step 26: f(x)= 126.22268636795532
# differential_evolution step 27: f(x)= 126.22268636795532
# differential_evolution step 28: f(x)= 126.22268636795532
# differential_evolution step 29: f(x)= 126.22268636795532
# differential_evolution step 30: f(x)= 126.22268636795532
# differential_evolution step 31: f(x)= 126.22268636795532
# differential_evolution step 32: f(x)= 126.22268636795532
# differential_evolution step 33: f(x)= 126.22268636795532
# differential_evolution step 34: f(x)= 126.22268636795532
# differential_evolution step 35: f(x)= 90.69037025254744
# differential_evolution step 36: f(x)= 90.69037025254744
# differential_evolution step 37: f(x)= 90.69037025254744
# differential_evolution step 38: f(x)= 90.69037025254744
# differential_evolution step 39: f(x)= 90.69037025254744
# differential_evolution step 40: f(x)= 86.93109501590885
# differential_evolution step 41: f(x)= 86.93109501590885
# differential_evolution step 42: f(x)= 86.93109501590885
# differential_evolution step 43: f(x)= 86.93109501590885
# differential_evolution step 44: f(x)= 86.93109501590885
# differential_evolution step 45: f(x)= 86.93109501590885
# differential_evolution step 46: f(x)= 86.93109501590885
# differential_evolution step 47: f(x)= 86.93109501590885
# differential_evolution step 48: f(x)= 86.93109501590885
# differential_evolution step 49: f(x)= 86.93109501590885
# differential_evolution step 50: f(x)= 86.93109501590885
# differential_evolution step 51: f(x)= 66.38878519614246
# differential_evolution step 52: f(x)= 66.38878519614246
# differential_evolution step 53: f(x)= 66.38878519614246
# differential_evolution step 54: f(x)= 66.38878519614246
# differential_evolution step 55: f(x)= 66.38878519614246
# differential_evolution step 56: f(x)= 66.38878519614246
# differential_evolution step 57: f(x)= 66.38878519614246
# differential_evolution step 58: f(x)= 66.38878519614246
# differential_evolution step 59: f(x)= 66.38878519614246
# differential_evolution step 60: f(x)= 66.38878519614246
# differential_evolution step 61: f(x)= 66.38878519614246
# differential_evolution step 62: f(x)= 66.38878519614246
# differential_evolution step 63: f(x)= 66.38878519614246
# differential_evolution step 64: f(x)= 66.38878519614246
# differential_evolution step 65: f(x)= 66.38878519614246
# differential_evolution step 66: f(x)= 66.38878519614246
# differential_evolution step 67: f(x)= 66.38878519614246
# differential_evolution step 68: f(x)= 66.38878519614246
# differential_evolution step 69: f(x)= 66.38878519614246
# differential_evolution step 70: f(x)= 66.38878519614246
# differential_evolution step 71: f(x)= 66.38878519614246
# differential_evolution step 72: f(x)= 66.38878519614246
# differential_evolution step 73: f(x)= 66.38878519614246
# differential_evolution step 74: f(x)= 66.38878519614246
# differential_evolution step 75: f(x)= 66.08545462997552
# differential_evolution step 76: f(x)= 66.08545462997552
# differential_evolution step 77: f(x)= 66.08545462997552
# differential_evolution step 78: f(x)= 66.08545462997552
# differential_evolution step 79: f(x)= 66.08545462997552
# differential_evolution step 80: f(x)= 66.08545462997552
# differential_evolution step 81: f(x)= 66.08545462997552
# differential_evolution step 82: f(x)= 64.49401827218473
# differential_evolution step 83: f(x)= 64.49401827218473
# differential_evolution step 84: f(x)= 64.49401827218473
# differential_evolution step 85: f(x)= 64.49401827218473
# differential_evolution step 86: f(x)= 64.49401827218473
# differential_evolution step 87: f(x)= 64.49401827218473
# differential_evolution step 88: f(x)= 64.49401827218473
# differential_evolution step 89: f(x)= 64.49401827218473
# differential_evolution step 90: f(x)= 64.49401827218473
# differential_evolution step 91: f(x)= 64.49401827218473
# differential_evolution step 92: f(x)= 64.49401827218473
# differential_evolution step 93: f(x)= 64.49401827218473
# differential_evolution step 94: f(x)= 62.12342701132345
# differential_evolution step 95: f(x)= 62.12342701132345
# differential_evolution step 96: f(x)= 62.12342701132345
# differential_evolution step 97: f(x)= 62.12342701132345
# differential_evolution step 98: f(x)= 62.12342701132345
# differential_evolution step 99: f(x)= 62.12342701132345
# differential_evolution step 100: f(x)= 62.12342701132345
# differential_evolution step 101: f(x)= 62.12342701132345
# differential_evolution step 102: f(x)= 62.12342701132345
# differential_evolution step 103: f(x)= 62.12342701132345
# differential_evolution step 104: f(x)= 60.384905714243004
# differential_evolution step 105: f(x)= 58.03852585895077
# differential_evolution step 106: f(x)= 58.03852585895077
# differential_evolution step 107: f(x)= 58.03852585895077
# differential_evolution step 108: f(x)= 58.03852585895077
# differential_evolution step 109: f(x)= 53.483577147007516
# differential_evolution step 110: f(x)= 53.483577147007516
# differential_evolution step 111: f(x)= 53.483577147007516
# differential_evolution step 112: f(x)= 53.483577147007516
# differential_evolution step 113: f(x)= 53.483577147007516
# differential_evolution step 114: f(x)= 53.483577147007516
# differential_evolution step 115: f(x)= 53.077168811975525
# differential_evolution step 116: f(x)= 53.077168811975525
# differential_evolution step 117: f(x)= 51.88373914265388
# differential_evolution step 118: f(x)= 51.88373914265388
# differential_evolution step 119: f(x)= 51.88373914265388
# differential_evolution step 120: f(x)= 51.88373914265388
# differential_evolution step 121: f(x)= 51.88373914265388
# differential_evolution step 122: f(x)= 51.88373914265388
# differential_evolution step 123: f(x)= 51.88373914265388
# differential_evolution step 124: f(x)= 51.88373914265388
# differential_evolution step 125: f(x)= 51.78325062279091
# differential_evolution step 126: f(x)= 51.78325062279091
# differential_evolution step 127: f(x)= 50.04557825280295
# differential_evolution step 128: f(x)= 50.04557825280295
# differential_evolution step 129: f(x)= 47.315766423360294
# differential_evolution step 130: f(x)= 47.315766423360294
# differential_evolution step 131: f(x)= 47.315766423360294
# differential_evolution step 132: f(x)= 47.315766423360294
# differential_evolution step 133: f(x)= 47.03292119113989
# differential_evolution step 134: f(x)= 47.03292119113989
# differential_evolution step 135: f(x)= 46.57970111580554
# differential_evolution step 136: f(x)= 46.57970111580554
# differential_evolution step 137: f(x)= 46.57970111580554
# differential_evolution step 138: f(x)= 46.57970111580554
# differential_evolution step 139: f(x)= 46.57970111580554
# differential_evolution step 140: f(x)= 46.57970111580554
# differential_evolution step 141: f(x)= 46.57970111580554
# differential_evolution step 142: f(x)= 46.57970111580554
# differential_evolution step 143: f(x)= 46.57970111580554
# differential_evolution step 144: f(x)= 46.57970111580554
# differential_evolution step 145: f(x)= 46.57970111580554
# differential_evolution step 146: f(x)= 46.57970111580554
# differential_evolution step 147: f(x)= 46.16749366797155
# differential_evolution step 148: f(x)= 46.00680882357299
# differential_evolution step 149: f(x)= 46.00680882357299
# differential_evolution step 150: f(x)= 46.00680882357299
# differential_evolution step 151: f(x)= 46.00680882357299
# differential_evolution step 152: f(x)= 46.00680882357299
# differential_evolution step 153: f(x)= 46.00680882357299
# differential_evolution step 154: f(x)= 46.00680882357299
# differential_evolution step 155: f(x)= 46.00680882357299
# differential_evolution step 156: f(x)= 44.71376788619269
# differential_evolution step 157: f(x)= 44.71376788619269
# differential_evolution step 158: f(x)= 44.71376788619269
# differential_evolution step 159: f(x)= 44.71376788619269
# differential_evolution step 160: f(x)= 44.71376788619269
# differential_evolution step 161: f(x)= 44.71376788619269
# differential_evolution step 162: f(x)= 44.71376788619269
# differential_evolution step 163: f(x)= 44.71376788619269
# differential_evolution step 164: f(x)= 44.71376788619269
# differential_evolution step 165: f(x)= 44.71376788619269
# differential_evolution step 166: f(x)= 44.71376788619269
# differential_evolution step 167: f(x)= 44.71376788619269
# differential_evolution step 168: f(x)= 44.71376788619269
# differential_evolution step 169: f(x)= 44.71376788619269
# differential_evolution step 170: f(x)= 44.71376788619269
# differential_evolution step 171: f(x)= 44.71376788619269
# differential_evolution step 172: f(x)= 44.71376788619269
# differential_evolution step 173: f(x)= 44.71376788619269
# differential_evolution step 174: f(x)= 44.71376788619269
# differential_evolution step 175: f(x)= 44.71376788619269
# differential_evolution step 176: f(x)= 44.50409094801193
# differential_evolution step 177: f(x)= 44.50409094801193
# differential_evolution step 178: f(x)= 44.50409094801193
# differential_evolution step 179: f(x)= 44.50409094801193
# differential_evolution step 180: f(x)= 44.50409094801193
# differential_evolution step 181: f(x)= 44.50409094801193
# differential_evolution step 182: f(x)= 44.13454228710865
# differential_evolution step 183: f(x)= 44.13454228710865
# differential_evolution step 184: f(x)= 44.13454228710865
# differential_evolution step 185: f(x)= 44.13454228710865
# differential_evolution step 186: f(x)= 44.13454228710865
# differential_evolution step 187: f(x)= 44.13454228710865
# differential_evolution step 188: f(x)= 44.13454228710865
# differential_evolution step 189: f(x)= 44.13454228710865
# differential_evolution step 190: f(x)= 43.894797945068476
# differential_evolution step 191: f(x)= 43.894797945068476
# differential_evolution step 192: f(x)= 43.894797945068476
# differential_evolution step 193: f(x)= 43.894797945068476
# differential_evolution step 194: f(x)= 43.894797945068476
# differential_evolution step 195: f(x)= 43.894797945068476
# differential_evolution step 196: f(x)= 43.894797945068476
# differential_evolution step 197: f(x)= 43.894797945068476
# differential_evolution step 198: f(x)= 43.894797945068476
# differential_evolution step 199: f(x)= 43.894797945068476
# differential_evolution step 200: f(x)= 43.894797945068476
# differential_evolution step 201: f(x)= 43.894797945068476
# differential_evolution step 202: f(x)= 43.894797945068476
# differential_evolution step 203: f(x)= 43.894797945068476
# differential_evolution step 204: f(x)= 43.894797945068476
# differential_evolution step 205: f(x)= 43.894797945068476
# differential_evolution step 206: f(x)= 43.894797945068476
# differential_evolution step 207: f(x)= 43.894797945068476
# differential_evolution step 208: f(x)= 43.894797945068476
# differential_evolution step 209: f(x)= 43.50342376267066
# differential_evolution step 210: f(x)= 43.50342376267066
# differential_evolution step 211: f(x)= 43.45639623529656
# differential_evolution step 212: f(x)= 43.45639623529656
# differential_evolution step 213: f(x)= 43.45639623529656
# differential_evolution step 214: f(x)= 43.45639623529656
# differential_evolution step 215: f(x)= 43.45639623529656
# differential_evolution step 216: f(x)= 43.45639623529656
# differential_evolution step 217: f(x)= 43.45639623529656
# differential_evolution step 218: f(x)= 43.45639623529656
# differential_evolution step 219: f(x)= 43.45639623529656
# differential_evolution step 220: f(x)= 43.45639623529656
# differential_evolution step 221: f(x)= 43.45639623529656
# differential_evolution step 222: f(x)= 43.45639623529656
# differential_evolution step 223: f(x)= 43.45639623529656
# differential_evolution step 224: f(x)= 43.45639623529656
# differential_evolution step 225: f(x)= 43.45639623529656
# differential_evolution step 226: f(x)= 43.45639623529656
# differential_evolution step 227: f(x)= 43.387956269865555
# differential_evolution step 228: f(x)= 43.387956269865555
# differential_evolution step 229: f(x)= 43.387956269865555
# differential_evolution step 230: f(x)= 43.387956269865555
# differential_evolution step 231: f(x)= 43.387956269865555
# differential_evolution step 232: f(x)= 43.387956269865555
# differential_evolution step 233: f(x)= 43.387956269865555
# differential_evolution step 234: f(x)= 43.387956269865555
# differential_evolution step 235: f(x)= 43.387956269865555
# differential_evolution step 236: f(x)= 43.387956269865555
# differential_evolution step 237: f(x)= 43.387956269865555
# differential_evolution step 238: f(x)= 43.387956269865555
# differential_evolution step 239: f(x)= 43.387956269865555
# differential_evolution step 240: f(x)= 43.387956269865555
# differential_evolution step 241: f(x)= 43.387956269865555
# differential_evolution step 242: f(x)= 43.387956269865555
# differential_evolution step 243: f(x)= 43.387956269865555
# differential_evolution step 244: f(x)= 43.25137067815786
# differential_evolution step 245: f(x)= 43.25137067815786
# differential_evolution step 246: f(x)= 43.25137067815786
# differential_evolution step 247: f(x)= 43.25137067815786
# differential_evolution step 248: f(x)= 43.25137067815786
# differential_evolution step 249: f(x)= 43.18649443097
# differential_evolution step 250: f(x)= 43.18649443097
# differential_evolution step 251: f(x)= 43.18649443097
# differential_evolution step 252: f(x)= 43.18649443097
# differential_evolution step 253: f(x)= 43.18649443097
# differential_evolution step 254: f(x)= 43.18649443097
# differential_evolution step 255: f(x)= 43.18649443097
# differential_evolution step 256: f(x)= 43.18649443097
# differential_evolution step 257: f(x)= 43.18649443097
# differential_evolution step 258: f(x)= 43.175113026148665
# differential_evolution step 259: f(x)= 43.175113026148665
# differential_evolution step 260: f(x)= 43.175113026148665
# differential_evolution step 261: f(x)= 43.175113026148665
# differential_evolution step 262: f(x)= 43.175113026148665
# differential_evolution step 263: f(x)= 43.175113026148665
# differential_evolution step 264: f(x)= 43.175113026148665
# differential_evolution step 265: f(x)= 43.175113026148665
# differential_evolution step 266: f(x)= 43.175113026148665
# differential_evolution step 267: f(x)= 43.175113026148665
# differential_evolution step 268: f(x)= 43.175113026148665
# differential_evolution step 269: f(x)= 43.16898176188107
# differential_evolution step 270: f(x)= 43.16898176188107
# differential_evolution step 271: f(x)= 43.16898176188107
# differential_evolution step 272: f(x)= 43.133750849681114
# differential_evolution step 273: f(x)= 43.133750849681114
# differential_evolution step 274: f(x)= 43.133750849681114
# differential_evolution step 275: f(x)= 43.133750849681114
# differential_evolution step 276: f(x)= 43.133750849681114
# differential_evolution step 277: f(x)= 43.133750849681114
# differential_evolution step 278: f(x)= 43.133750849681114
# differential_evolution step 279: f(x)= 43.133750849681114
# differential_evolution step 280: f(x)= 43.133750849681114
# differential_evolution step 281: f(x)= 43.11404228743197
# differential_evolution step 282: f(x)= 43.11404228743197
# differential_evolution step 283: f(x)= 43.11404228743197
# differential_evolution step 284: f(x)= 43.05863831106686
# differential_evolution step 285: f(x)= 43.05863831106686
# differential_evolution step 286: f(x)= 43.05863831106686
# differential_evolution step 287: f(x)= 43.05863831106686
# differential_evolution step 288: f(x)= 43.05863831106686
# differential_evolution step 289: f(x)= 43.05863831106686
# differential_evolution step 290: f(x)= 43.01227821965235
# differential_evolution step 291: f(x)= 43.01227821965235
# differential_evolution step 292: f(x)= 43.01227821965235
# differential_evolution step 293: f(x)= 43.01227821965235
# differential_evolution step 294: f(x)= 43.01227821965235
# differential_evolution step 295: f(x)= 43.01227821965235
# differential_evolution step 296: f(x)= 43.01227821965235
# differential_evolution step 297: f(x)= 43.01227821965235
# differential_evolution step 298: f(x)= 43.01227821965235
# differential_evolution step 299: f(x)= 43.01227821965235
# differential_evolution step 300: f(x)= 43.01227821965235
# differential_evolution step 301: f(x)= 43.01227821965235
# differential_evolution step 302: f(x)= 43.01227821965235
# differential_evolution step 303: f(x)= 43.01227821965235
# differential_evolution step 304: f(x)= 43.01227821965235
# differential_evolution step 305: f(x)= 43.01227821965235
# differential_evolution step 306: f(x)= 43.01227821965235
# differential_evolution step 307: f(x)= 42.988264476943606
# differential_evolution step 308: f(x)= 42.988264476943606
# differential_evolution step 309: f(x)= 42.988264476943606
# differential_evolution step 310: f(x)= 42.988264476943606
# differential_evolution step 311: f(x)= 42.988264476943606
# differential_evolution step 312: f(x)= 42.988264476943606
# differential_evolution step 313: f(x)= 42.988264476943606
# differential_evolution step 314: f(x)= 42.988264476943606
# differential_evolution step 315: f(x)= 42.988264476943606
# differential_evolution step 316: f(x)= 42.988264476943606
# differential_evolution step 317: f(x)= 42.988264476943606
# differential_evolution step 318: f(x)= 42.98559703461742
# differential_evolution step 319: f(x)= 42.98559703461742
# differential_evolution step 320: f(x)= 42.97253090423218
# differential_evolution step 321: f(x)= 42.97253090423218
# differential_evolution step 322: f(x)= 42.97253090423218
# differential_evolution step 323: f(x)= 42.97253090423218
# differential_evolution step 324: f(x)= 42.97253090423218
# differential_evolution step 325: f(x)= 42.97253090423218
# differential_evolution step 326: f(x)= 42.97253090423218
# differential_evolution step 327: f(x)= 42.97253090423218
# differential_evolution step 328: f(x)= 42.97190777620546
# differential_evolution step 329: f(x)= 42.952238041725444
# differential_evolution step 330: f(x)= 42.952238041725444
# differential_evolution step 331: f(x)= 42.952238041725444
# differential_evolution step 332: f(x)= 42.952238041725444
# differential_evolution step 333: f(x)= 42.952238041725444
# differential_evolution step 334: f(x)= 42.952238041725444
# differential_evolution step 335: f(x)= 42.952238041725444
# differential_evolution step 336: f(x)= 42.952238041725444
# differential_evolution step 337: f(x)= 42.952238041725444
# differential_evolution step 338: f(x)= 42.952238041725444
# differential_evolution step 339: f(x)= 42.952238041725444
# differential_evolution step 340: f(x)= 42.952238041725444
# differential_evolution step 341: f(x)= 42.952238041725444
# differential_evolution step 342: f(x)= 42.952238041725444
# differential_evolution step 343: f(x)= 42.952238041725444
# differential_evolution step 344: f(x)= 42.952238041725444
# differential_evolution step 345: f(x)= 42.952238041725444
# differential_evolution step 346: f(x)= 42.952238041725444
# differential_evolution step 347: f(x)= 42.952238041725444
# differential_evolution step 348: f(x)= 42.952238041725444
# differential_evolution step 349: f(x)= 42.952238041725444
# differential_evolution step 350: f(x)= 42.952238041725444
# differential_evolution step 351: f(x)= 42.952238041725444
# differential_evolution step 352: f(x)= 42.952238041725444
# differential_evolution step 353: f(x)= 42.95182707744893
# differential_evolution step 354: f(x)= 42.94584790430312
# differential_evolution step 355: f(x)= 42.890155500999406
# differential_evolution step 356: f(x)= 42.890155500999406
# differential_evolution step 357: f(x)= 42.890155500999406
# differential_evolution step 358: f(x)= 42.88535413555548
# differential_evolution step 359: f(x)= 42.88535413555548
# differential_evolution step 360: f(x)= 42.88535413555548
# differential_evolution step 361: f(x)= 42.88535413555548
# differential_evolution step 362: f(x)= 42.87101545817333
# differential_evolution step 363: f(x)= 42.87101545817333
# differential_evolution step 364: f(x)= 42.853832581108556
# differential_evolution step 365: f(x)= 42.853832581108556
# differential_evolution step 366: f(x)= 42.820006349973895
# differential_evolution step 367: f(x)= 42.81694400221512
# differential_evolution step 368: f(x)= 42.81575304619055
# differential_evolution step 369: f(x)= 42.81575304619055
# differential_evolution step 370: f(x)= 42.81575304619055
# differential_evolution step 371: f(x)= 42.760017735648745
# differential_evolution step 372: f(x)= 42.75773245933626
# differential_evolution step 373: f(x)= 42.727591538614284
# differential_evolution step 374: f(x)= 42.727591538614284
# differential_evolution step 375: f(x)= 42.727591538614284
# differential_evolution step 376: f(x)= 42.727591538614284
# differential_evolution step 377: f(x)= 42.721727479154126
# differential_evolution step 378: f(x)= 42.721727479154126
# differential_evolution step 379: f(x)= 42.721727479154126
# differential_evolution step 380: f(x)= 42.721727479154126
# differential_evolution step 381: f(x)= 42.70000801836215
# differential_evolution step 382: f(x)= 42.70000801836215
# differential_evolution step 383: f(x)= 42.70000801836215
# differential_evolution step 384: f(x)= 42.65839886819641
# differential_evolution step 385: f(x)= 42.65839886819641
# differential_evolution step 386: f(x)= 42.59633520965878
# differential_evolution step 387: f(x)= 42.59633520965878
# differential_evolution step 388: f(x)= 42.59633520965878
# differential_evolution step 389: f(x)= 42.59633520965878
# differential_evolution step 390: f(x)= 42.59633520965878
# differential_evolution step 391: f(x)= 42.55149528947958
# differential_evolution step 392: f(x)= 42.53451568128696
# differential_evolution step 393: f(x)= 42.53451568128696
# differential_evolution step 394: f(x)= 42.53451568128696
# differential_evolution step 395: f(x)= 42.53451568128696
# differential_evolution step 396: f(x)= 42.50311754099669
# differential_evolution step 397: f(x)= 42.45745823976365
# differential_evolution step 398: f(x)= 42.45745823976365
# differential_evolution step 399: f(x)= 42.45745823976365
# differential_evolution step 400: f(x)= 42.45745823976365
# differential_evolution step 401: f(x)= 42.45745823976365
# differential_evolution step 402: f(x)= 42.45745823976365
# differential_evolution step 403: f(x)= 42.45745823976365
# differential_evolution step 404: f(x)= 42.45745823976365
# differential_evolution step 405: f(x)= 42.45745823976365
# differential_evolution step 406: f(x)= 42.45745823976365
# differential_evolution step 407: f(x)= 42.45745823976365
# differential_evolution step 408: f(x)= 42.45745823976365
# differential_evolution step 409: f(x)= 42.45745823976365
# differential_evolution step 410: f(x)= 42.45745823976365
# differential_evolution step 411: f(x)= 42.453489122588664
# differential_evolution step 412: f(x)= 42.453489122588664
# differential_evolution step 413: f(x)= 42.453489122588664
# differential_evolution step 414: f(x)= 42.453489122588664
# differential_evolution step 415: f(x)= 42.453489122588664
# differential_evolution step 416: f(x)= 42.453489122588664
# differential_evolution step 417: f(x)= 42.453489122588664
# differential_evolution step 418: f(x)= 42.453489122588664
# differential_evolution step 419: f(x)= 42.38477188791684
# differential_evolution step 420: f(x)= 42.38477188791684
# differential_evolution step 421: f(x)= 42.38477188791684
# differential_evolution step 422: f(x)= 42.38477188791684
# differential_evolution step 423: f(x)= 42.38477188791684
# differential_evolution step 424: f(x)= 42.38477188791684
# differential_evolution step 425: f(x)= 42.38477188791684
# differential_evolution step 426: f(x)= 42.38477188791684
# differential_evolution step 427: f(x)= 42.38477188791684
# differential_evolution step 428: f(x)= 42.38477188791684
# differential_evolution step 429: f(x)= 42.38477188791684
# differential_evolution step 430: f(x)= 42.38477188791684
# differential_evolution step 431: f(x)= 42.38108754893331
# differential_evolution step 432: f(x)= 42.38108754893331
# differential_evolution step 433: f(x)= 42.38108754893331
# differential_evolution step 434: f(x)= 42.38108754893331
# differential_evolution step 435: f(x)= 42.38108754893331
# differential_evolution step 436: f(x)= 42.38108754893331
# differential_evolution step 437: f(x)= 42.38108754893331
# differential_evolution step 438: f(x)= 42.38108754893331
# differential_evolution step 439: f(x)= 42.38108754893331
# differential_evolution step 440: f(x)= 42.37152418139074
# differential_evolution step 441: f(x)= 42.37152418139074
# differential_evolution step 442: f(x)= 42.37152418139074
# differential_evolution step 443: f(x)= 42.37152418139074
# differential_evolution step 444: f(x)= 42.37152418139074
# differential_evolution step 445: f(x)= 42.37152418139074
# differential_evolution step 446: f(x)= 42.37152418139074
# differential_evolution step 447: f(x)= 42.37152418139074
# differential_evolution step 448: f(x)= 42.37152418139074
# differential_evolution step 449: f(x)= 42.3558748751866
# differential_evolution step 450: f(x)= 42.3558748751866
# differential_evolution step 451: f(x)= 42.3558748751866
# differential_evolution step 452: f(x)= 42.3558748751866
# differential_evolution step 453: f(x)= 42.3558748751866
# differential_evolution step 454: f(x)= 42.3558748751866
# differential_evolution step 455: f(x)= 42.3558748751866
# differential_evolution step 456: f(x)= 42.3558748751866
# differential_evolution step 457: f(x)= 42.3558748751866
# differential_evolution step 458: f(x)= 42.3558748751866
# differential_evolution step 459: f(x)= 42.3558748751866
# differential_evolution step 460: f(x)= 42.3558748751866
# differential_evolution step 461: f(x)= 42.3558748751866
# differential_evolution step 462: f(x)= 42.3558748751866
# differential_evolution step 463: f(x)= 42.3558748751866
# differential_evolution step 464: f(x)= 42.3558748751866
# differential_evolution step 465: f(x)= 42.3558748751866
# differential_evolution step 466: f(x)= 42.3558748751866
# differential_evolution step 467: f(x)= 42.3558748751866
# differential_evolution step 468: f(x)= 42.3558748751866
# differential_evolution step 469: f(x)= 42.3558748751866
# differential_evolution step 470: f(x)= 42.3558748751866
# differential_evolution step 471: f(x)= 42.3558748751866
# differential_evolution step 472: f(x)= 42.3558748751866
# differential_evolution step 473: f(x)= 42.3558748751866
# differential_evolution step 474: f(x)= 42.3558748751866
# differential_evolution step 475: f(x)= 42.3558748751866
# differential_evolution step 476: f(x)= 42.3558748751866
# differential_evolution step 477: f(x)= 42.3558748751866
# differential_evolution step 478: f(x)= 42.3558748751866
# differential_evolution step 479: f(x)= 42.3558748751866
# differential_evolution step 480: f(x)= 42.3558748751866
# differential_evolution step 481: f(x)= 42.3558748751866
# differential_evolution step 482: f(x)= 42.3558748751866
# differential_evolution step 483: f(x)= 42.3558748751866
# differential_evolution step 484: f(x)= 42.3558748751866
# differential_evolution step 485: f(x)= 42.3558748751866
# differential_evolution step 486: f(x)= 42.3558748751866
# differential_evolution step 487: f(x)= 42.3558748751866
# differential_evolution step 488: f(x)= 42.3558748751866
# differential_evolution step 489: f(x)= 42.3558748751866
# differential_evolution step 490: f(x)= 42.350311270205914
# differential_evolution step 491: f(x)= 42.350311270205914
# differential_evolution step 492: f(x)= 42.350311270205914
# differential_evolution step 493: f(x)= 42.350311270205914
# differential_evolution step 494: f(x)= 42.350311270205914
# differential_evolution step 495: f(x)= 42.350311270205914
# differential_evolution step 496: f(x)= 42.350311270205914
# differential_evolution step 497: f(x)= 42.350311270205914
# differential_evolution step 498: f(x)= 42.350311270205914
# differential_evolution step 499: f(x)= 42.350311270205914
# differential_evolution step 500: f(x)= 42.34983781507503
# differential_evolution step 501: f(x)= 42.33133926295664
# differential_evolution step 502: f(x)= 42.33133926295664
# differential_evolution step 503: f(x)= 42.33133926295664
# differential_evolution step 504: f(x)= 42.33133926295664
# differential_evolution step 505: f(x)= 42.33133926295664
# differential_evolution step 506: f(x)= 42.33133926295664
# differential_evolution step 507: f(x)= 42.33133926295664
# differential_evolution step 508: f(x)= 42.33133926295664
# differential_evolution step 509: f(x)= 42.33133926295664
# differential_evolution step 510: f(x)= 42.33133926295664
# differential_evolution step 511: f(x)= 42.33133926295664
# differential_evolution step 512: f(x)= 42.33133926295664
# differential_evolution step 513: f(x)= 42.33133926295664
# differential_evolution step 514: f(x)= 42.33133926295664
# differential_evolution step 515: f(x)= 42.33133926295664
# differential_evolution step 516: f(x)= 42.33133926295664
# differential_evolution step 517: f(x)= 42.33133926295664
# differential_evolution step 518: f(x)= 42.33133926295664
# differential_evolution step 519: f(x)= 42.33133926295664
# differential_evolution step 520: f(x)= 42.33133926295664
# differential_evolution step 521: f(x)= 42.33133926295664
# differential_evolution step 522: f(x)= 42.33133926295664
# differential_evolution step 523: f(x)= 42.33133926295664
# differential_evolution step 524: f(x)= 42.33133926295664
# differential_evolution step 525: f(x)= 42.33133926295664
# differential_evolution step 526: f(x)= 42.33133926295664
# differential_evolution step 527: f(x)= 42.33133926295664
# differential_evolution step 528: f(x)= 42.33133926295664
# differential_evolution step 529: f(x)= 42.33133926295664
# differential_evolution step 530: f(x)= 42.33133926295664
# differential_evolution step 531: f(x)= 42.33133926295664
# differential_evolution step 532: f(x)= 42.33133926295664
# differential_evolution step 533: f(x)= 42.33133926295664
# differential_evolution step 534: f(x)= 42.33133926295664
# differential_evolution step 535: f(x)= 42.33133926295664
# differential_evolution step 536: f(x)= 42.33133926295664
# differential_evolution step 537: f(x)= 42.33133926295664
# differential_evolution step 538: f(x)= 42.33133926295664
# differential_evolution step 539: f(x)= 42.33133926295664
# differential_evolution step 540: f(x)= 42.33133926295664
# differential_evolution step 541: f(x)= 42.33133926295664
# differential_evolution step 542: f(x)= 42.33133926295664
# differential_evolution step 543: f(x)= 42.33133926295664
# differential_evolution step 544: f(x)= 42.33133926295664
# differential_evolution step 545: f(x)= 42.33133926295664
# differential_evolution step 546: f(x)= 42.33079087516963
# differential_evolution step 547: f(x)= 42.33079087516963
# differential_evolution step 548: f(x)= 42.33079087516963
# differential_evolution step 549: f(x)= 42.33079087516963
# differential_evolution step 550: f(x)= 42.33079087516963
# differential_evolution step 551: f(x)= 42.33079087516963
# differential_evolution step 552: f(x)= 42.33079087516963
# differential_evolution step 553: f(x)= 42.33079087516963
# differential_evolution step 554: f(x)= 42.33079087516963
# differential_evolution step 555: f(x)= 42.33020921574547
# differential_evolution step 556: f(x)= 42.33020921574547
# differential_evolution step 557: f(x)= 42.33020921574547
# differential_evolution step 558: f(x)= 42.33020921574547
# differential_evolution step 559: f(x)= 42.33020921574547
# differential_evolution step 560: f(x)= 42.33020921574547
# differential_evolution step 561: f(x)= 42.33020921574547
# differential_evolution step 562: f(x)= 42.32965116364968
# differential_evolution step 563: f(x)= 42.32965116364968
# differential_evolution step 564: f(x)= 42.32965116364968
# differential_evolution step 565: f(x)= 42.32965116364968
# differential_evolution step 566: f(x)= 42.32965116364968
# differential_evolution step 567: f(x)= 42.32965116364968
# differential_evolution step 568: f(x)= 42.32952590771501
# differential_evolution step 569: f(x)= 42.32952590771501
# differential_evolution step 570: f(x)= 42.32952590771501
# differential_evolution step 571: f(x)= 42.3282696024037
# differential_evolution step 572: f(x)= 42.3282696024037
# differential_evolution step 573: f(x)= 42.3282696024037
# differential_evolution step 574: f(x)= 42.3282696024037
# differential_evolution step 575: f(x)= 42.3282696024037
# differential_evolution step 576: f(x)= 42.3282696024037
# differential_evolution step 577: f(x)= 42.3282696024037
# differential_evolution step 578: f(x)= 42.328232683072166
# differential_evolution step 579: f(x)= 42.328232683072166
# differential_evolution step 580: f(x)= 42.328232683072166
# differential_evolution step 581: f(x)= 42.328232683072166
# differential_evolution step 582: f(x)= 42.32757679932921
# differential_evolution step 583: f(x)= 42.32757679932921
# differential_evolution step 584: f(x)= 42.32757679932921
# differential_evolution step 585: f(x)= 42.32757679932921
# differential_evolution step 586: f(x)= 42.32757679932921
# differential_evolution step 587: f(x)= 42.32757679932921
# differential_evolution step 588: f(x)= 42.32757679932921
# differential_evolution step 589: f(x)= 42.32757679932921
# differential_evolution step 590: f(x)= 42.32757679932921
# differential_evolution step 591: f(x)= 42.32642317223539
# differential_evolution step 592: f(x)= 42.32642317223539
# differential_evolution step 593: f(x)= 42.32642317223539
# differential_evolution step 594: f(x)= 42.32642317223539
# differential_evolution step 595: f(x)= 42.32642317223539
# differential_evolution step 596: f(x)= 42.32642317223539
# differential_evolution step 597: f(x)= 42.32556323223178
# differential_evolution step 598: f(x)= 42.32556323223178
# differential_evolution step 599: f(x)= 42.32538746243245
# differential_evolution step 600: f(x)= 42.32538746243245
# differential_evolution step 601: f(x)= 42.32538746243245
# differential_evolution step 602: f(x)= 42.32538746243245
# differential_evolution step 603: f(x)= 42.325083587465336
# differential_evolution step 604: f(x)= 42.325083587465336
# differential_evolution step 605: f(x)= 42.32449865663043
# differential_evolution step 606: f(x)= 42.32449865663043
# differential_evolution step 607: f(x)= 42.32449865663043
# differential_evolution step 608: f(x)= 42.32449865663043
# differential_evolution step 609: f(x)= 42.32449865663043
# differential_evolution step 610: f(x)= 42.32449865663043
# differential_evolution step 611: f(x)= 42.32449865663043
# differential_evolution step 612: f(x)= 42.323563075626346
# differential_evolution step 613: f(x)= 42.323563075626346
# differential_evolution step 614: f(x)= 42.323563075626346
# differential_evolution step 615: f(x)= 42.323563075626346
# differential_evolution step 616: f(x)= 42.32348427314158
# differential_evolution step 617: f(x)= 42.32348427314158
# differential_evolution step 618: f(x)= 42.32332174025401
# differential_evolution step 619: f(x)= 42.32332174025401
# differential_evolution step 620: f(x)= 42.32332174025401
# differential_evolution step 621: f(x)= 42.32332174025401
# differential_evolution step 622: f(x)= 42.32332174025401
# differential_evolution step 623: f(x)= 42.32332174025401
# differential_evolution step 624: f(x)= 42.32332174025401
# differential_evolution step 625: f(x)= 42.32332174025401
# differential_evolution step 626: f(x)= 42.32332174025401
# differential_evolution step 627: f(x)= 42.32332174025401
# differential_evolution step 628: f(x)= 42.32332174025401
# differential_evolution step 629: f(x)= 42.32332174025401
# differential_evolution step 630: f(x)= 42.32332174025401
# differential_evolution step 631: f(x)= 42.32316306735469
# differential_evolution step 632: f(x)= 42.32316306735469
# differential_evolution step 633: f(x)= 42.32316306735469
# differential_evolution step 634: f(x)= 42.32316306735469
# differential_evolution step 635: f(x)= 42.32316306735469
# differential_evolution step 636: f(x)= 42.32316306735469
# differential_evolution step 637: f(x)= 42.32316306735469
# differential_evolution step 638: f(x)= 42.32316306735469
# differential_evolution step 639: f(x)= 42.32308119153852
# differential_evolution step 640: f(x)= 42.32308119153852
# differential_evolution step 641: f(x)= 42.32308119153852
# differential_evolution step 642: f(x)= 42.32308119153852
# differential_evolution step 643: f(x)= 42.32308119153852
# differential_evolution step 644: f(x)= 42.32308119153852
# differential_evolution step 645: f(x)= 42.32308119153852
# differential_evolution step 646: f(x)= 42.32308119153852
# differential_evolution step 647: f(x)= 42.32308119153852
# differential_evolution step 648: f(x)= 42.32308119153852
# differential_evolution step 649: f(x)= 42.32300487682005
# differential_evolution step 650: f(x)= 42.32300487682005
# differential_evolution step 651: f(x)= 42.32300487682005
# differential_evolution step 652: f(x)= 42.32300487682005
# differential_evolution step 653: f(x)= 42.32300487682005
# differential_evolution step 654: f(x)= 42.32300487682005
# differential_evolution step 655: f(x)= 42.32300487682005
# differential_evolution step 656: f(x)= 42.32300487682005
# differential_evolution step 657: f(x)= 42.32300487682005
# differential_evolution step 658: f(x)= 42.32184428729633
# differential_evolution step 659: f(x)= 42.32184428729633
# differential_evolution step 660: f(x)= 42.32184428729633
# differential_evolution step 661: f(x)= 42.32166020689935
# differential_evolution step 662: f(x)= 42.32166020689935
# differential_evolution step 663: f(x)= 42.32166020689935
# differential_evolution step 664: f(x)= 42.32166020689935
# differential_evolution step 665: f(x)= 42.32166020689935
# differential_evolution step 666: f(x)= 42.32166020689935
# differential_evolution step 667: f(x)= 42.32166020689935
# differential_evolution step 668: f(x)= 42.32166020689935
# differential_evolution step 669: f(x)= 42.32166020689935
# differential_evolution step 670: f(x)= 42.32166020689935
# differential_evolution step 671: f(x)= 42.32166020689935
# differential_evolution step 672: f(x)= 42.32166020689935
# differential_evolution step 673: f(x)= 42.32166020689935
# differential_evolution step 674: f(x)= 42.32166020689935
# differential_evolution step 675: f(x)= 42.32166020689935
# differential_evolution step 676: f(x)= 42.32166020689935
# differential_evolution step 677: f(x)= 42.32166020689935
# differential_evolution step 678: f(x)= 42.32166020689935
# differential_evolution step 679: f(x)= 42.32166020689935
# differential_evolution step 680: f(x)= 42.32166020689935
# differential_evolution step 681: f(x)= 42.32166020689935
# differential_evolution step 682: f(x)= 42.32166020689935
# differential_evolution step 683: f(x)= 42.32166020689935
# differential_evolution step 684: f(x)= 42.32166020689935
# differential_evolution step 685: f(x)= 42.32166020689935
# differential_evolution step 686: f(x)= 42.32166020689935
# differential_evolution step 687: f(x)= 42.32166020689935
# differential_evolution step 688: f(x)= 42.32166020689935
# differential_evolution step 689: f(x)= 42.32166020689935
# differential_evolution step 690: f(x)= 42.32166020689935
# differential_evolution step 691: f(x)= 42.32166020689935
# differential_evolution step 692: f(x)= 42.32166020689935
# differential_evolution step 693: f(x)= 42.32166020689935
# differential_evolution step 694: f(x)= 42.32147297547164
# differential_evolution step 695: f(x)= 42.32147297547164
# differential_evolution step 696: f(x)= 42.32147297547164
# differential_evolution step 697: f(x)= 42.32147297547164
# differential_evolution step 698: f(x)= 42.32147297547164
# differential_evolution step 699: f(x)= 42.32147297547164
# differential_evolution step 700: f(x)= 42.32147297547164
# differential_evolution step 701: f(x)= 42.32147297547164
# differential_evolution step 702: f(x)= 42.32147297547164
# differential_evolution step 703: f(x)= 42.32147297547164
# differential_evolution step 704: f(x)= 42.32147297547164
# differential_evolution step 705: f(x)= 42.32147297547164
# differential_evolution step 706: f(x)= 42.32147297547164
# differential_evolution step 707: f(x)= 42.32147297547164
# differential_evolution step 708: f(x)= 42.32147297547164
# differential_evolution step 709: f(x)= 42.321371294328834
# differential_evolution step 710: f(x)= 42.321371294328834
# differential_evolution step 711: f(x)= 42.321371294328834
# differential_evolution step 712: f(x)= 42.32127782781554
# differential_evolution step 713: f(x)= 42.32127782781554
# differential_evolution step 714: f(x)= 42.32127782781554
# differential_evolution step 715: f(x)= 42.32127782781554
# differential_evolution step 716: f(x)= 42.32127782781554
# differential_evolution step 717: f(x)= 42.32127782781554
# differential_evolution step 718: f(x)= 42.32127782781554
# differential_evolution step 719: f(x)= 42.32127782781554
# differential_evolution step 720: f(x)= 42.32085691366582
# differential_evolution step 721: f(x)= 42.32085691366582
# differential_evolution step 722: f(x)= 42.32085691366582
# differential_evolution step 723: f(x)= 42.32085691366582
# differential_evolution step 724: f(x)= 42.32085691366582
# differential_evolution step 725: f(x)= 42.32085691366582
# differential_evolution step 726: f(x)= 42.32085691366582
# differential_evolution step 727: f(x)= 42.32085691366582
# differential_evolution step 728: f(x)= 42.32085691366582
# differential_evolution step 729: f(x)= 42.32085691366582
# differential_evolution step 730: f(x)= 42.32085691366582
# differential_evolution step 731: f(x)= 42.32085691366582
# differential_evolution step 732: f(x)= 42.32085691366582
# differential_evolution step 733: f(x)= 42.32085691366582
# differential_evolution step 734: f(x)= 42.32085691366582
# differential_evolution step 735: f(x)= 42.32085691366582
# differential_evolution step 736: f(x)= 42.32085691366582
# differential_evolution step 737: f(x)= 42.32085691366582
# differential_evolution step 738: f(x)= 42.32085691366582
# differential_evolution step 739: f(x)= 42.32085691366582
# differential_evolution step 740: f(x)= 42.32082033941601
# differential_evolution step 741: f(x)= 42.32082033941601
# differential_evolution step 742: f(x)= 42.32082033941601
# differential_evolution step 743: f(x)= 42.32082033941601
# differential_evolution step 744: f(x)= 42.32082033941601
# differential_evolution step 745: f(x)= 42.32082033941601
# differential_evolution step 746: f(x)= 42.32082033941601
# differential_evolution step 747: f(x)= 42.32082033941601
# differential_evolution step 748: f(x)= 42.32082033941601
# differential_evolution step 749: f(x)= 42.32082033941601
# differential_evolution step 750: f(x)= 42.32082033941601
# differential_evolution step 751: f(x)= 42.32082033941601
# differential_evolution step 752: f(x)= 42.32082033941601
# differential_evolution step 753: f(x)= 42.32082033941601
# differential_evolution step 754: f(x)= 42.32082033941601
# differential_evolution step 755: f(x)= 42.32082033941601
# differential_evolution step 756: f(x)= 42.32082033941601
# differential_evolution step 757: f(x)= 42.32082033941601
# differential_evolution step 758: f(x)= 42.32082033941601
# differential_evolution step 759: f(x)= 42.32082033941601
# differential_evolution step 760: f(x)= 42.32082033941601
# differential_evolution step 761: f(x)= 42.32082033941601
# differential_evolution step 762: f(x)= 42.32082033941601
# differential_evolution step 763: f(x)= 42.32082033941601
# differential_evolution step 764: f(x)= 42.320615433183626
# differential_evolution step 765: f(x)= 42.320615433183626
# differential_evolution step 766: f(x)= 42.320615433183626
# differential_evolution step 767: f(x)= 42.320615433183626
# differential_evolution step 768: f(x)= 42.320615433183626
# differential_evolution step 769: f(x)= 42.320615433183626
# differential_evolution step 770: f(x)= 42.320615433183626
# differential_evolution step 771: f(x)= 42.320615433183626
# differential_evolution step 772: f(x)= 42.320615433183626
# differential_evolution step 773: f(x)= 42.320615433183626
# differential_evolution step 774: f(x)= 42.320615433183626
# differential_evolution step 775: f(x)= 42.320615433183626
# differential_evolution step 776: f(x)= 42.320615433183626
# differential_evolution step 777: f(x)= 42.320615433183626
# differential_evolution step 778: f(x)= 42.320615433183626
# differential_evolution step 779: f(x)= 42.320346794351615
# differential_evolution step 780: f(x)= 42.320346794351615
# differential_evolution step 781: f(x)= 42.320346794351615
# differential_evolution step 782: f(x)= 42.320346794351615
# differential_evolution step 783: f(x)= 42.320346794351615
# differential_evolution step 784: f(x)= 42.320346794351615
# differential_evolution step 785: f(x)= 42.320346794351615
# differential_evolution step 786: f(x)= 42.320346794351615
# differential_evolution step 787: f(x)= 42.320346794351615
# differential_evolution step 788: f(x)= 42.320346794351615
# differential_evolution step 789: f(x)= 42.320346794351615
# differential_evolution step 790: f(x)= 42.320346794351615
# differential_evolution step 791: f(x)= 42.320346794351615
# differential_evolution step 792: f(x)= 42.320346794351615
# differential_evolution step 793: f(x)= 42.320346794351615
# differential_evolution step 794: f(x)= 42.320346794351615
# differential_evolution step 795: f(x)= 42.320346794351615
# differential_evolution step 796: f(x)= 42.320346794351615
# differential_evolution step 797: f(x)= 42.320346794351615
# differential_evolution step 798: f(x)= 42.320346794351615
# differential_evolution step 799: f(x)= 42.320346794351615
# differential_evolution step 800: f(x)= 42.320346794351615
# differential_evolution step 801: f(x)= 42.320346794351615
# differential_evolution step 802: f(x)= 42.320346794351615
# differential_evolution step 803: f(x)= 42.32026430675821
# differential_evolution step 804: f(x)= 42.32026430675821
# differential_evolution step 805: f(x)= 42.32026430675821
# differential_evolution step 806: f(x)= 42.32026430675821
# differential_evolution step 807: f(x)= 42.32026430675821
# differential_evolution step 808: f(x)= 42.32026430675821
# differential_evolution step 809: f(x)= 42.32026430675821
# differential_evolution step 810: f(x)= 42.32026430675821
# differential_evolution step 811: f(x)= 42.32026430675821
# differential_evolution step 812: f(x)= 42.32026430675821
# differential_evolution step 813: f(x)= 42.32026430675821
# differential_evolution step 814: f(x)= 42.32026430675821
# differential_evolution step 815: f(x)= 42.32026430675821
# differential_evolution step 816: f(x)= 42.32026430675821
# differential_evolution step 817: f(x)= 42.32026430675821
# differential_evolution step 818: f(x)= 42.32026430675821
# differential_evolution step 819: f(x)= 42.32026430675821
# differential_evolution step 820: f(x)= 42.32026430675821
# differential_evolution step 821: f(x)= 42.32026430675821
# differential_evolution step 822: f(x)= 42.32026430675821
# differential_evolution step 823: f(x)= 42.32018500668143
# differential_evolution step 824: f(x)= 42.32018500668143
# differential_evolution step 825: f(x)= 42.32018500668143
# differential_evolution step 826: f(x)= 42.32018500668143
# differential_evolution step 827: f(x)= 42.32018500668143
# differential_evolution step 828: f(x)= 42.32018500668143
# differential_evolution step 829: f(x)= 42.32018500668143
# differential_evolution step 830: f(x)= 42.32018500668143
# differential_evolution step 831: f(x)= 42.32018500668143
# differential_evolution step 832: f(x)= 42.32018500668143
# differential_evolution step 833: f(x)= 42.32018500668143
# differential_evolution step 834: f(x)= 42.32018500668143
# differential_evolution step 835: f(x)= 42.32018500668143
# differential_evolution step 836: f(x)= 42.32018500668143
# differential_evolution step 837: f(x)= 42.32018500668143
# differential_evolution step 838: f(x)= 42.32018500668143
# differential_evolution step 839: f(x)= 42.32018500668143
# differential_evolution step 840: f(x)= 42.32018500668143
# differential_evolution step 841: f(x)= 42.32018500668143
# differential_evolution step 842: f(x)= 42.32018500668143
# differential_evolution step 843: f(x)= 42.32018500668143
# differential_evolution step 844: f(x)= 42.32018500668143
# differential_evolution step 845: f(x)= 42.32018500668143
# differential_evolution step 846: f(x)= 42.32018500668143
# differential_evolution step 847: f(x)= 42.32018500668143
# differential_evolution step 848: f(x)= 42.32018500668143
# differential_evolution step 849: f(x)= 42.320175326298376
# differential_evolution step 850: f(x)= 42.320175326298376
# differential_evolution step 851: f(x)= 42.320175326298376
# differential_evolution step 852: f(x)= 42.320175326298376
# differential_evolution step 853: f(x)= 42.320175326298376
# differential_evolution step 854: f(x)= 42.320175326298376
# differential_evolution step 855: f(x)= 42.320175326298376
# differential_evolution step 856: f(x)= 42.320175326298376
# differential_evolution step 857: f(x)= 42.320175326298376
# differential_evolution step 858: f(x)= 42.320175326298376
# differential_evolution step 859: f(x)= 42.320175326298376
# differential_evolution step 860: f(x)= 42.320175326298376
# differential_evolution step 861: f(x)= 42.320175326298376
# differential_evolution step 862: f(x)= 42.320175326298376
# differential_evolution step 863: f(x)= 42.320175326298376
# differential_evolution step 864: f(x)= 42.320175326298376
# differential_evolution step 865: f(x)= 42.32016116438177
# differential_evolution step 866: f(x)= 42.32016116438177
# differential_evolution step 867: f(x)= 42.32016116438177
# differential_evolution step 868: f(x)= 42.320144784669814
# differential_evolution step 869: f(x)= 42.320144784669814
# differential_evolution step 870: f(x)= 42.320144784669814
# differential_evolution step 871: f(x)= 42.320144784669814
# differential_evolution step 872: f(x)= 42.320144784669814
# differential_evolution step 873: f(x)= 42.320144784669814
# differential_evolution step 874: f(x)= 42.320144784669814
# differential_evolution step 875: f(x)= 42.320144784669814
# differential_evolution step 876: f(x)= 42.320144784669814
# differential_evolution step 877: f(x)= 42.320144784669814
# differential_evolution step 878: f(x)= 42.320129293635
# differential_evolution step 879: f(x)= 42.320129293635
# differential_evolution step 880: f(x)= 42.320129293635
# differential_evolution step 881: f(x)= 42.32011793906515
# differential_evolution step 882: f(x)= 42.32011793906515
# differential_evolution step 883: f(x)= 42.32011793906515
# differential_evolution step 884: f(x)= 42.32011793906515
# differential_evolution step 885: f(x)= 42.32011793906515
# differential_evolution step 886: f(x)= 42.32011793906515
# differential_evolution step 887: f(x)= 42.32011793906515
# differential_evolution step 888: f(x)= 42.32011793906515
# differential_evolution step 889: f(x)= 42.32011793906515
# differential_evolution step 890: f(x)= 42.32011793906515
# differential_evolution step 891: f(x)= 42.32011793906515
# differential_evolution step 892: f(x)= 42.32011793906515
# differential_evolution step 893: f(x)= 42.32011793906515
# differential_evolution step 894: f(x)= 42.32011793906515
# differential_evolution step 895: f(x)= 42.32011793906515
# differential_evolution step 896: f(x)= 42.32011793906515
# differential_evolution step 897: f(x)= 42.32011793906515
# differential_evolution step 898: f(x)= 42.32011793906515
# differential_evolution step 899: f(x)= 42.32008866187034
# differential_evolution step 900: f(x)= 42.32008866187034
# differential_evolution step 901: f(x)= 42.32008866187034
# differential_evolution step 902: f(x)= 42.32008866187034
# differential_evolution step 903: f(x)= 42.32008866187034
# differential_evolution step 904: f(x)= 42.32008866187034
# differential_evolution step 905: f(x)= 42.32008866187034
# differential_evolution step 906: f(x)= 42.32008866187034
# differential_evolution step 907: f(x)= 42.3200870609601
# differential_evolution step 908: f(x)= 42.3200870609601
# differential_evolution step 909: f(x)= 42.3200870609601
# differential_evolution step 910: f(x)= 42.3200870609601
# differential_evolution step 911: f(x)= 42.3200870609601
# differential_evolution step 912: f(x)= 42.320071378218
# differential_evolution step 913: f(x)= 42.320071378218
# differential_evolution step 914: f(x)= 42.320071378218
# differential_evolution step 915: f(x)= 42.320071378218
# differential_evolution step 916: f(x)= 42.320071378218
# differential_evolution step 917: f(x)= 42.320071378218
# differential_evolution step 918: f(x)= 42.320071378218
# differential_evolution step 919: f(x)= 42.320071378218
# differential_evolution step 920: f(x)= 42.320071378218
# differential_evolution step 921: f(x)= 42.320071378218
# differential_evolution step 922: f(x)= 42.320071378218
# differential_evolution step 923: f(x)= 42.320071378218
# differential_evolution step 924: f(x)= 42.320071378218
# differential_evolution step 925: f(x)= 42.320071378218
# differential_evolution step 926: f(x)= 42.320071378218
# differential_evolution step 927: f(x)= 42.320071378218
# differential_evolution step 928: f(x)= 42.320071378218
# differential_evolution step 929: f(x)= 42.320071378218
# differential_evolution step 930: f(x)= 42.320071378218
# differential_evolution step 931: f(x)= 42.320071378218
# differential_evolution step 932: f(x)= 42.320071378218
# differential_evolution step 933: f(x)= 42.32006107548064
# differential_evolution step 934: f(x)= 42.32006107548064
# differential_evolution step 935: f(x)= 42.32006107548064
# differential_evolution step 936: f(x)= 42.32006107548064
# differential_evolution step 937: f(x)= 42.32006107548064
# differential_evolution step 938: f(x)= 42.32006107548064
# differential_evolution step 939: f(x)= 42.32006107548064
# differential_evolution step 940: f(x)= 42.32006107548064
# differential_evolution step 941: f(x)= 42.32006107548064
# differential_evolution step 942: f(x)= 42.32005373606114
# differential_evolution step 943: f(x)= 42.32005373606114
# differential_evolution step 944: f(x)= 42.32005373606114
# differential_evolution step 945: f(x)= 42.32002774623228
# differential_evolution step 946: f(x)= 42.32002774623228
# differential_evolution step 947: f(x)= 42.32002774623228
# differential_evolution step 948: f(x)= 42.32002774623228
# differential_evolution step 949: f(x)= 42.32002774623228
# differential_evolution step 950: f(x)= 42.32002774623228
# differential_evolution step 951: f(x)= 42.32002774623228
# differential_evolution step 952: f(x)= 42.32002774623228
# differential_evolution step 953: f(x)= 42.32001136325616
# differential_evolution step 954: f(x)= 42.32001136325616
# differential_evolution step 955: f(x)= 42.32001136325616
# differential_evolution step 956: f(x)= 42.32001136325616
# differential_evolution step 957: f(x)= 42.32001136325616
# differential_evolution step 958: f(x)= 42.32001136325616
# differential_evolution step 959: f(x)= 42.32001136325616
# differential_evolution step 960: f(x)= 42.32001136325616
# differential_evolution step 961: f(x)= 42.32001136325616
# differential_evolution step 962: f(x)= 42.32001136325616
# differential_evolution step 963: f(x)= 42.32001136325616
# differential_evolution step 964: f(x)= 42.32001136325616
# differential_evolution step 965: f(x)= 42.32001136325616
# differential_evolution step 966: f(x)= 42.32001136325616
# differential_evolution step 967: f(x)= 42.32001136325616
# differential_evolution step 968: f(x)= 42.32001136325616
# differential_evolution step 969: f(x)= 42.32001136325616
# differential_evolution step 970: f(x)= 42.32001136325616
# differential_evolution step 971: f(x)= 42.32001136325616
# differential_evolution step 972: f(x)= 42.32001136325616
# differential_evolution step 973: f(x)= 42.32001136325616
# differential_evolution step 974: f(x)= 42.32001136325616
# differential_evolution step 975: f(x)= 42.32001136325616
# differential_evolution step 976: f(x)= 42.32001136325616
# differential_evolution step 977: f(x)= 42.32001136325616
# differential_evolution step 978: f(x)= 42.32001136325616
# differential_evolution step 979: f(x)= 42.32001136325616
# differential_evolution step 980: f(x)= 42.32001136325616
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=4.0653, r_e=2.1174, n=0.1001, x_0=43.8000
# Sérsic 2: I_e=1.9707, r_e=15.8390, n=1.2442, x_0=51.1463
# Sérsic 3: I_e=8.6069, r_e=3.7626, n=0.5595, x_0=59.5384
# Chi quadro minimo: 42.31999849233643
# True

# %%
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = radial_profile_error_HB, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, radial_profile_error_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.0221, r_e=8.0002, n=1.3519, x_0=44.1126
# Sérsic 2: I_e=0.6672, r_e=21.0609, n=1.9012, x_0=51.1958
# Sérsic 3: I_e=7.2123, r_e=4.8120, n=0.7237, x_0=59.5384
# [0.28742379 1.62488107 0.20460024 0.19667299 0.37566904 4.83757597
#  0.49082232 0.06055838 0.44371033 0.24225212 0.05039107 0.10697836]
# 51.56293137990535

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 8022.545378918796
# differential_evolution step 2: f(x)= 5057.861739599244
# differential_evolution step 3: f(x)= 533.4902690639659
# differential_evolution step 4: f(x)= 533.4902690639659
# differential_evolution step 5: f(x)= 482.7581628351614
# differential_evolution step 6: f(x)= 482.7581628351614
# differential_evolution step 7: f(x)= 351.9934052122314
# differential_evolution step 8: f(x)= 158.38744493527764
# differential_evolution step 9: f(x)= 158.38744493527764
# differential_evolution step 10: f(x)= 158.38744493527764
# differential_evolution step 11: f(x)= 158.38744493527764
# differential_evolution step 12: f(x)= 71.07053407051784
# differential_evolution step 13: f(x)= 71.07053407051784
# differential_evolution step 14: f(x)= 71.07053407051784
# differential_evolution step 15: f(x)= 39.92156723791397
# differential_evolution step 16: f(x)= 39.92156723791397
# differential_evolution step 17: f(x)= 35.680490898067355
# differential_evolution step 18: f(x)= 35.680490898067355
# differential_evolution step 19: f(x)= 35.680490898067355
# differential_evolution step 20: f(x)= 35.680490898067355
# differential_evolution step 21: f(x)= 35.680490898067355
# differential_evolution step 22: f(x)= 28.47863473502861
# differential_evolution step 23: f(x)= 28.47863473502861
# differential_evolution step 24: f(x)= 24.843338211449336
# differential_evolution step 25: f(x)= 24.843338211449336
# differential_evolution step 26: f(x)= 20.033776605358494
# differential_evolution step 27: f(x)= 20.033776605358494
# differential_evolution step 28: f(x)= 20.033776605358494
# differential_evolution step 29: f(x)= 12.937116277778498
# differential_evolution step 30: f(x)= 12.937116277778498
# differential_evolution step 31: f(x)= 12.937116277778498
# differential_evolution step 32: f(x)= 12.937116277778498
# differential_evolution step 33: f(x)= 12.937116277778498
# differential_evolution step 34: f(x)= 12.937116277778498
# differential_evolution step 35: f(x)= 12.937116277778498
# differential_evolution step 36: f(x)= 12.937116277778498
# differential_evolution step 37: f(x)= 12.937116277778498
# differential_evolution step 38: f(x)= 12.937116277778498
# differential_evolution step 39: f(x)= 12.741876648438001
# differential_evolution step 40: f(x)= 12.741876648438001
# differential_evolution step 41: f(x)= 12.741876648438001
# differential_evolution step 42: f(x)= 12.741876648438001
# differential_evolution step 43: f(x)= 12.741876648438001
# differential_evolution step 44: f(x)= 12.741876648438001
# differential_evolution step 45: f(x)= 9.970952483657241
# differential_evolution step 46: f(x)= 9.970952483657241
# differential_evolution step 47: f(x)= 9.970952483657241
# differential_evolution step 48: f(x)= 9.970952483657241
# differential_evolution step 49: f(x)= 7.578560999465054
# differential_evolution step 50: f(x)= 7.578560999465054
# differential_evolution step 51: f(x)= 7.578560999465054
# differential_evolution step 52: f(x)= 7.578560999465054
# differential_evolution step 53: f(x)= 7.578560999465054
# differential_evolution step 54: f(x)= 7.578560999465054
# differential_evolution step 55: f(x)= 7.578560999465054
# differential_evolution step 56: f(x)= 7.578560999465054
# differential_evolution step 57: f(x)= 7.578560999465054
# differential_evolution step 58: f(x)= 4.905896235672015
# differential_evolution step 59: f(x)= 4.905896235672015
# differential_evolution step 60: f(x)= 4.905896235672015
# differential_evolution step 61: f(x)= 4.905896235672015
# differential_evolution step 62: f(x)= 4.905896235672015
# differential_evolution step 63: f(x)= 4.905896235672015
# differential_evolution step 64: f(x)= 4.905896235672015
# differential_evolution step 65: f(x)= 4.905896235672015
# differential_evolution step 66: f(x)= 4.905896235672015
# differential_evolution step 67: f(x)= 4.905896235672015
# differential_evolution step 68: f(x)= 4.905896235672015
# differential_evolution step 69: f(x)= 4.905896235672015
# differential_evolution step 70: f(x)= 4.905896235672015
# differential_evolution step 71: f(x)= 4.905896235672015
# differential_evolution step 72: f(x)= 4.905896235672015
# differential_evolution step 73: f(x)= 4.905896235672015
# differential_evolution step 74: f(x)= 4.905896235672015
# differential_evolution step 75: f(x)= 4.905896235672015
# differential_evolution step 76: f(x)= 4.905896235672015
# differential_evolution step 77: f(x)= 4.228858342361166
# differential_evolution step 78: f(x)= 4.228858342361166
# differential_evolution step 79: f(x)= 4.228858342361166
# differential_evolution step 80: f(x)= 4.228858342361166
# differential_evolution step 81: f(x)= 4.228858342361166
# differential_evolution step 82: f(x)= 4.228858342361166
# differential_evolution step 83: f(x)= 4.228858342361166
# differential_evolution step 84: f(x)= 4.228858342361166
# differential_evolution step 85: f(x)= 4.228858342361166
# differential_evolution step 86: f(x)= 4.228858342361166
# differential_evolution step 87: f(x)= 4.228858342361166
# differential_evolution step 88: f(x)= 4.228858342361166
# differential_evolution step 89: f(x)= 4.228858342361166
# differential_evolution step 90: f(x)= 4.228858342361166
# differential_evolution step 91: f(x)= 4.228858342361166
# differential_evolution step 92: f(x)= 4.228858342361166
# differential_evolution step 93: f(x)= 4.228858342361166
# differential_evolution step 94: f(x)= 4.228858342361166
# differential_evolution step 95: f(x)= 4.228858342361166
# differential_evolution step 96: f(x)= 4.228858342361166
# differential_evolution step 97: f(x)= 4.228858342361166
# differential_evolution step 98: f(x)= 3.894961810190717
# differential_evolution step 99: f(x)= 3.894961810190717
# differential_evolution step 100: f(x)= 3.894961810190717
# differential_evolution step 101: f(x)= 3.894961810190717
# differential_evolution step 102: f(x)= 3.894961810190717
# differential_evolution step 103: f(x)= 3.5381252546612902
# differential_evolution step 104: f(x)= 3.5381252546612902
# differential_evolution step 105: f(x)= 3.5381252546612902
# differential_evolution step 106: f(x)= 3.5381252546612902
# differential_evolution step 107: f(x)= 2.970155538586636
# differential_evolution step 108: f(x)= 2.970155538586636
# differential_evolution step 109: f(x)= 2.970155538586636
# differential_evolution step 110: f(x)= 2.970155538586636
# differential_evolution step 111: f(x)= 2.970155538586636
# differential_evolution step 112: f(x)= 2.970155538586636
# differential_evolution step 113: f(x)= 2.970155538586636
# differential_evolution step 114: f(x)= 2.970155538586636
# differential_evolution step 115: f(x)= 2.970155538586636
# differential_evolution step 116: f(x)= 2.970155538586636
# differential_evolution step 117: f(x)= 2.970155538586636
# differential_evolution step 118: f(x)= 2.970155538586636
# differential_evolution step 119: f(x)= 2.970155538586636
# differential_evolution step 120: f(x)= 2.970155538586636
# differential_evolution step 121: f(x)= 2.970155538586636
# differential_evolution step 122: f(x)= 2.970155538586636
# differential_evolution step 123: f(x)= 2.970155538586636
# differential_evolution step 124: f(x)= 2.970155538586636
# differential_evolution step 125: f(x)= 2.7781540143815033
# differential_evolution step 126: f(x)= 2.7781540143815033
# differential_evolution step 127: f(x)= 2.7781540143815033
# differential_evolution step 128: f(x)= 2.7253784354791706
# differential_evolution step 129: f(x)= 2.7253784354791706
# differential_evolution step 130: f(x)= 2.7253784354791706
# differential_evolution step 131: f(x)= 2.7068418139778703
# differential_evolution step 132: f(x)= 2.7068418139778703
# differential_evolution step 133: f(x)= 2.639313615878176
# differential_evolution step 134: f(x)= 2.4905139254430293
# differential_evolution step 135: f(x)= 2.4041316557819292
# differential_evolution step 136: f(x)= 2.4041316557819292
# differential_evolution step 137: f(x)= 2.4041316557819292
# differential_evolution step 138: f(x)= 2.4041316557819292
# differential_evolution step 139: f(x)= 2.4041316557819292
# differential_evolution step 140: f(x)= 2.4041316557819292
# differential_evolution step 141: f(x)= 2.4041316557819292
# differential_evolution step 142: f(x)= 2.4041316557819292
# differential_evolution step 143: f(x)= 2.4041316557819292
# differential_evolution step 144: f(x)= 2.4041316557819292
# differential_evolution step 145: f(x)= 2.4041316557819292
# differential_evolution step 146: f(x)= 2.4041316557819292
# differential_evolution step 147: f(x)= 2.4041316557819292
# differential_evolution step 148: f(x)= 2.4041316557819292
# differential_evolution step 149: f(x)= 2.4041316557819292
# differential_evolution step 150: f(x)= 2.4041316557819292
# differential_evolution step 151: f(x)= 2.4041316557819292
# differential_evolution step 152: f(x)= 2.4041316557819292
# differential_evolution step 153: f(x)= 2.4041316557819292
# differential_evolution step 154: f(x)= 2.4041316557819292
# differential_evolution step 155: f(x)= 2.4041316557819292
# differential_evolution step 156: f(x)= 2.4041316557819292
# differential_evolution step 157: f(x)= 2.4041316557819292
# differential_evolution step 158: f(x)= 2.4041316557819292
# differential_evolution step 159: f(x)= 2.4041316557819292
# differential_evolution step 160: f(x)= 2.4041316557819292
# differential_evolution step 161: f(x)= 2.4041316557819292
# differential_evolution step 162: f(x)= 2.4041316557819292
# differential_evolution step 163: f(x)= 2.4041316557819292
# differential_evolution step 164: f(x)= 2.2955641214823834
# differential_evolution step 165: f(x)= 2.2955641214823834
# differential_evolution step 166: f(x)= 2.2955641214823834
# differential_evolution step 167: f(x)= 2.2955641214823834
# differential_evolution step 168: f(x)= 2.2955641214823834
# differential_evolution step 169: f(x)= 2.2955641214823834
# differential_evolution step 170: f(x)= 2.2955641214823834
# differential_evolution step 171: f(x)= 2.254539761457316
# differential_evolution step 172: f(x)= 2.254539761457316
# differential_evolution step 173: f(x)= 2.254539761457316
# differential_evolution step 174: f(x)= 2.254539761457316
# differential_evolution step 175: f(x)= 2.254539761457316
# differential_evolution step 176: f(x)= 2.254539761457316
# differential_evolution step 177: f(x)= 2.254539761457316
# differential_evolution step 178: f(x)= 2.1840744475515237
# differential_evolution step 179: f(x)= 2.1840744475515237
# differential_evolution step 180: f(x)= 2.1840744475515237
# differential_evolution step 181: f(x)= 2.1840744475515237
# differential_evolution step 182: f(x)= 2.1840744475515237
# differential_evolution step 183: f(x)= 2.1840744475515237
# differential_evolution step 184: f(x)= 2.1840744475515237
# differential_evolution step 185: f(x)= 2.1840744475515237
# differential_evolution step 186: f(x)= 2.1840744475515237
# differential_evolution step 187: f(x)= 2.1840744475515237
# differential_evolution step 188: f(x)= 2.1840744475515237
# differential_evolution step 189: f(x)= 2.1840744475515237
# differential_evolution step 190: f(x)= 2.1305071404869595
# differential_evolution step 191: f(x)= 2.1305071404869595
# differential_evolution step 192: f(x)= 2.1305071404869595
# differential_evolution step 193: f(x)= 2.1305071404869595
# differential_evolution step 194: f(x)= 2.1305071404869595
# differential_evolution step 195: f(x)= 2.1305071404869595
# differential_evolution step 196: f(x)= 2.1305071404869595
# differential_evolution step 197: f(x)= 2.1305071404869595
# differential_evolution step 198: f(x)= 2.1305071404869595
# differential_evolution step 199: f(x)= 2.088112569333369
# differential_evolution step 200: f(x)= 2.088112569333369
# differential_evolution step 201: f(x)= 2.088112569333369
# differential_evolution step 202: f(x)= 2.088112569333369
# differential_evolution step 203: f(x)= 2.088112569333369
# differential_evolution step 204: f(x)= 2.088112569333369
# differential_evolution step 205: f(x)= 2.088112569333369
# differential_evolution step 206: f(x)= 2.088112569333369
# differential_evolution step 207: f(x)= 2.088112569333369
# differential_evolution step 208: f(x)= 2.0867442016122246
# differential_evolution step 209: f(x)= 2.0867442016122246
# differential_evolution step 210: f(x)= 2.073377321903375
# differential_evolution step 211: f(x)= 2.073377321903375
# differential_evolution step 212: f(x)= 2.073377321903375
# differential_evolution step 213: f(x)= 2.073377321903375
# differential_evolution step 214: f(x)= 2.054889734492746
# differential_evolution step 215: f(x)= 2.054889734492746
# differential_evolution step 216: f(x)= 2.054889734492746
# differential_evolution step 217: f(x)= 2.054889734492746
# differential_evolution step 218: f(x)= 2.054889734492746
# differential_evolution step 219: f(x)= 2.054889734492746
# differential_evolution step 220: f(x)= 2.054889734492746
# differential_evolution step 221: f(x)= 2.054889734492746
# differential_evolution step 222: f(x)= 2.054889734492746
# differential_evolution step 223: f(x)= 2.0207732060609835
# differential_evolution step 224: f(x)= 2.0207732060609835
# differential_evolution step 225: f(x)= 2.0207732060609835
# differential_evolution step 226: f(x)= 2.0207732060609835
# differential_evolution step 227: f(x)= 2.0207732060609835
# differential_evolution step 228: f(x)= 2.0207732060609835
# differential_evolution step 229: f(x)= 2.0207732060609835
# differential_evolution step 230: f(x)= 2.019344284761041
# differential_evolution step 231: f(x)= 1.9953282821501197
# differential_evolution step 232: f(x)= 1.9953282821501197
# differential_evolution step 233: f(x)= 1.9953282821501197
# differential_evolution step 234: f(x)= 1.9953282821501197
# differential_evolution step 235: f(x)= 1.9953282821501197
# differential_evolution step 236: f(x)= 1.9953282821501197
# differential_evolution step 237: f(x)= 1.9953282821501197
# differential_evolution step 238: f(x)= 1.9953282821501197
# differential_evolution step 239: f(x)= 1.9953282821501197
# differential_evolution step 240: f(x)= 1.9953282821501197
# differential_evolution step 241: f(x)= 1.9953282821501197
# differential_evolution step 242: f(x)= 1.9953282821501197
# differential_evolution step 243: f(x)= 1.9953282821501197
# differential_evolution step 244: f(x)= 1.9953282821501197
# differential_evolution step 245: f(x)= 1.9953282821501197
# differential_evolution step 246: f(x)= 1.9953282821501197
# differential_evolution step 247: f(x)= 1.9953282821501197
# differential_evolution step 248: f(x)= 1.9953282821501197
# differential_evolution step 249: f(x)= 1.9953282821501197
# differential_evolution step 250: f(x)= 1.9953282821501197
# differential_evolution step 251: f(x)= 1.9953282821501197
# differential_evolution step 252: f(x)= 1.9953282821501197
# differential_evolution step 253: f(x)= 1.9953282821501197
# differential_evolution step 254: f(x)= 1.9953282821501197
# differential_evolution step 255: f(x)= 1.9953282821501197
# differential_evolution step 256: f(x)= 1.9941003083081696
# differential_evolution step 257: f(x)= 1.9941003083081696
# differential_evolution step 258: f(x)= 1.9941003083081696
# differential_evolution step 259: f(x)= 1.9941003083081696
# differential_evolution step 260: f(x)= 1.9941003083081696
# differential_evolution step 261: f(x)= 1.9755406412188483
# differential_evolution step 262: f(x)= 1.9755406412188483
# differential_evolution step 263: f(x)= 1.9755406412188483
# differential_evolution step 264: f(x)= 1.9755406412188483
# differential_evolution step 265: f(x)= 1.9755406412188483
# differential_evolution step 266: f(x)= 1.9755406412188483
# differential_evolution step 267: f(x)= 1.9755406412188483
# differential_evolution step 268: f(x)= 1.9755406412188483
# differential_evolution step 269: f(x)= 1.9755406412188483
# differential_evolution step 270: f(x)= 1.9755406412188483
# differential_evolution step 271: f(x)= 1.9755406412188483
# differential_evolution step 272: f(x)= 1.9528102046989149
# differential_evolution step 273: f(x)= 1.9407067612291127
# differential_evolution step 274: f(x)= 1.9407067612291127
# differential_evolution step 275: f(x)= 1.9407067612291127
# differential_evolution step 276: f(x)= 1.9407067612291127
# differential_evolution step 277: f(x)= 1.9407067612291127
# differential_evolution step 278: f(x)= 1.9407067612291127
# differential_evolution step 279: f(x)= 1.9407067612291127
# differential_evolution step 280: f(x)= 1.9407067612291127
# differential_evolution step 281: f(x)= 1.9407067612291127
# differential_evolution step 282: f(x)= 1.9407067612291127
# differential_evolution step 283: f(x)= 1.9407067612291127
# differential_evolution step 284: f(x)= 1.9407067612291127
# differential_evolution step 285: f(x)= 1.9407067612291127
# differential_evolution step 286: f(x)= 1.9407067612291127
# differential_evolution step 287: f(x)= 1.9407067612291127
# differential_evolution step 288: f(x)= 1.9407067612291127
# differential_evolution step 289: f(x)= 1.9407067612291127
# differential_evolution step 290: f(x)= 1.9407067612291127
# differential_evolution step 291: f(x)= 1.9407067612291127
# differential_evolution step 292: f(x)= 1.9407067612291127
# differential_evolution step 293: f(x)= 1.9407067612291127
# differential_evolution step 294: f(x)= 1.9348920986925662
# differential_evolution step 295: f(x)= 1.9348920986925662
# differential_evolution step 296: f(x)= 1.9348920986925662
# differential_evolution step 297: f(x)= 1.9348920986925662
# differential_evolution step 298: f(x)= 1.9348920986925662
# differential_evolution step 299: f(x)= 1.9348920986925662
# differential_evolution step 300: f(x)= 1.9348920986925662
# differential_evolution step 301: f(x)= 1.9348920986925662
# differential_evolution step 302: f(x)= 1.9348920986925662
# differential_evolution step 303: f(x)= 1.9348920986925662
# differential_evolution step 304: f(x)= 1.9348920986925662
# differential_evolution step 305: f(x)= 1.9348920986925662
# differential_evolution step 306: f(x)= 1.9348920986925662
# differential_evolution step 307: f(x)= 1.9348920986925662
# differential_evolution step 308: f(x)= 1.9348920986925662
# differential_evolution step 309: f(x)= 1.9348920986925662
# differential_evolution step 310: f(x)= 1.9348920986925662
# differential_evolution step 311: f(x)= 1.9348920986925662
# differential_evolution step 312: f(x)= 1.9348920986925662
# differential_evolution step 313: f(x)= 1.9348920986925662
# differential_evolution step 314: f(x)= 1.9348920986925662
# differential_evolution step 315: f(x)= 1.9348920986925662
# differential_evolution step 316: f(x)= 1.9348920986925662
# differential_evolution step 317: f(x)= 1.9348920986925662
# differential_evolution step 318: f(x)= 1.9348920986925662
# differential_evolution step 319: f(x)= 1.9348920986925662
# differential_evolution step 320: f(x)= 1.9332831079530852
# differential_evolution step 321: f(x)= 1.927725342675569
# differential_evolution step 322: f(x)= 1.927725342675569
# differential_evolution step 323: f(x)= 1.927725342675569
# differential_evolution step 324: f(x)= 1.927725342675569
# differential_evolution step 325: f(x)= 1.927725342675569
# differential_evolution step 326: f(x)= 1.927725342675569
# differential_evolution step 327: f(x)= 1.927725342675569
# differential_evolution step 328: f(x)= 1.927725342675569
# differential_evolution step 329: f(x)= 1.927725342675569
# differential_evolution step 330: f(x)= 1.927725342675569
# differential_evolution step 331: f(x)= 1.9272923701424798
# differential_evolution step 332: f(x)= 1.9272923701424798
# differential_evolution step 333: f(x)= 1.9272923701424798
# differential_evolution step 334: f(x)= 1.9272923701424798
# differential_evolution step 335: f(x)= 1.926178679725714
# differential_evolution step 336: f(x)= 1.926178679725714
# differential_evolution step 337: f(x)= 1.926178679725714
# differential_evolution step 338: f(x)= 1.926178679725714
# differential_evolution step 339: f(x)= 1.926178679725714
# differential_evolution step 340: f(x)= 1.926178679725714
# differential_evolution step 341: f(x)= 1.926178679725714
# differential_evolution step 342: f(x)= 1.926178679725714
# differential_evolution step 343: f(x)= 1.926178679725714
# differential_evolution step 344: f(x)= 1.926178679725714
# differential_evolution step 345: f(x)= 1.924199831661522
# differential_evolution step 346: f(x)= 1.924199831661522
# differential_evolution step 347: f(x)= 1.924199831661522
# differential_evolution step 348: f(x)= 1.924199831661522
# differential_evolution step 349: f(x)= 1.924199831661522
# differential_evolution step 350: f(x)= 1.924199831661522
# differential_evolution step 351: f(x)= 1.924199831661522
# differential_evolution step 352: f(x)= 1.9236548547656571
# differential_evolution step 353: f(x)= 1.9215189368496592
# differential_evolution step 354: f(x)= 1.91820978592145
# differential_evolution step 355: f(x)= 1.91820978592145
# differential_evolution step 356: f(x)= 1.91820978592145
# differential_evolution step 357: f(x)= 1.91820978592145
# differential_evolution step 358: f(x)= 1.9143445602082243
# differential_evolution step 359: f(x)= 1.9143445602082243
# differential_evolution step 360: f(x)= 1.9143445602082243
# differential_evolution step 361: f(x)= 1.9143445602082243
# differential_evolution step 362: f(x)= 1.9143445602082243
# differential_evolution step 363: f(x)= 1.9143445602082243
# differential_evolution step 364: f(x)= 1.9143445602082243
# differential_evolution step 365: f(x)= 1.9143445602082243
# differential_evolution step 366: f(x)= 1.9143445602082243
# differential_evolution step 367: f(x)= 1.9143445602082243
# differential_evolution step 368: f(x)= 1.9143445602082243
# differential_evolution step 369: f(x)= 1.9143445602082243
# differential_evolution step 370: f(x)= 1.9143445602082243
# differential_evolution step 371: f(x)= 1.9143445602082243
# differential_evolution step 372: f(x)= 1.9143445602082243
# differential_evolution step 373: f(x)= 1.9143445602082243
# differential_evolution step 374: f(x)= 1.9143445602082243
# differential_evolution step 375: f(x)= 1.9143445602082243
# differential_evolution step 376: f(x)= 1.9143445602082243
# differential_evolution step 377: f(x)= 1.9143445602082243
# differential_evolution step 378: f(x)= 1.9143445602082243
# differential_evolution step 379: f(x)= 1.9143445602082243
# differential_evolution step 380: f(x)= 1.9143445602082243
# differential_evolution step 381: f(x)= 1.9143445602082243
# differential_evolution step 382: f(x)= 1.9143445602082243
# differential_evolution step 383: f(x)= 1.9143445602082243
# differential_evolution step 384: f(x)= 1.9143445602082243
# differential_evolution step 385: f(x)= 1.9143445602082243
# differential_evolution step 386: f(x)= 1.9143445602082243
# differential_evolution step 387: f(x)= 1.9143445602082243
# differential_evolution step 388: f(x)= 1.9143445602082243
# differential_evolution step 389: f(x)= 1.9143445602082243
# differential_evolution step 390: f(x)= 1.9143445602082243
# differential_evolution step 391: f(x)= 1.9143445602082243
# differential_evolution step 392: f(x)= 1.9143445602082243
# differential_evolution step 393: f(x)= 1.913973061453059
# differential_evolution step 394: f(x)= 1.913973061453059
# differential_evolution step 395: f(x)= 1.913973061453059
# differential_evolution step 396: f(x)= 1.913973061453059
# differential_evolution step 397: f(x)= 1.913973061453059
# differential_evolution step 398: f(x)= 1.913973061453059
# differential_evolution step 399: f(x)= 1.913973061453059
# differential_evolution step 400: f(x)= 1.913973061453059
# differential_evolution step 401: f(x)= 1.913973061453059
# differential_evolution step 402: f(x)= 1.913973061453059
# differential_evolution step 403: f(x)= 1.913973061453059
# differential_evolution step 404: f(x)= 1.913539565504949
# differential_evolution step 405: f(x)= 1.913539565504949
# differential_evolution step 406: f(x)= 1.913539565504949
# differential_evolution step 407: f(x)= 1.913539565504949
# differential_evolution step 408: f(x)= 1.913539565504949
# differential_evolution step 409: f(x)= 1.912540327289546
# differential_evolution step 410: f(x)= 1.9124335452032981
# differential_evolution step 411: f(x)= 1.9124335452032981
# differential_evolution step 412: f(x)= 1.9124335452032981
# differential_evolution step 413: f(x)= 1.9124335452032981
# differential_evolution step 414: f(x)= 1.9124335452032981
# differential_evolution step 415: f(x)= 1.9124335452032981
# differential_evolution step 416: f(x)= 1.9124335452032981
# differential_evolution step 417: f(x)= 1.9124335452032981
# differential_evolution step 418: f(x)= 1.9124335452032981
# differential_evolution step 419: f(x)= 1.9124335452032981
# differential_evolution step 420: f(x)= 1.9124335452032981
# differential_evolution step 421: f(x)= 1.9124335452032981
# differential_evolution step 422: f(x)= 1.9122630583902593
# differential_evolution step 423: f(x)= 1.9122630583902593
# differential_evolution step 424: f(x)= 1.9122630583902593
# differential_evolution step 425: f(x)= 1.9122630583902593
# differential_evolution step 426: f(x)= 1.9122630583902593
# differential_evolution step 427: f(x)= 1.9122630583902593
# differential_evolution step 428: f(x)= 1.9112908600182577
# differential_evolution step 429: f(x)= 1.9112908600182577
# differential_evolution step 430: f(x)= 1.9112908600182577
# differential_evolution step 431: f(x)= 1.9112908600182577
# differential_evolution step 432: f(x)= 1.9112908600182577
# differential_evolution step 433: f(x)= 1.9112908600182577
# differential_evolution step 434: f(x)= 1.9112908600182577
# differential_evolution step 435: f(x)= 1.9112908600182577
# differential_evolution step 436: f(x)= 1.9112908600182577
# differential_evolution step 437: f(x)= 1.9112908600182577
# differential_evolution step 438: f(x)= 1.9112908600182577
# differential_evolution step 439: f(x)= 1.9112908600182577
# differential_evolution step 440: f(x)= 1.9112908600182577
# differential_evolution step 441: f(x)= 1.9110305288477314
# differential_evolution step 442: f(x)= 1.9110305288477314
# differential_evolution step 443: f(x)= 1.9110305288477314
# differential_evolution step 444: f(x)= 1.9110305288477314
# differential_evolution step 445: f(x)= 1.9110305288477314
# differential_evolution step 446: f(x)= 1.9110305288477314
# differential_evolution step 447: f(x)= 1.9110305288477314
# differential_evolution step 448: f(x)= 1.9110305288477314
# differential_evolution step 449: f(x)= 1.9110305288477314
# differential_evolution step 450: f(x)= 1.910712948742577
# differential_evolution step 451: f(x)= 1.910712948742577
# differential_evolution step 452: f(x)= 1.910712948742577
# differential_evolution step 453: f(x)= 1.910712948742577
# differential_evolution step 454: f(x)= 1.910712948742577
# differential_evolution step 455: f(x)= 1.910712948742577
# differential_evolution step 456: f(x)= 1.910712948742577
# differential_evolution step 457: f(x)= 1.910712948742577
# differential_evolution step 458: f(x)= 1.910712948742577
# differential_evolution step 459: f(x)= 1.910712948742577
# differential_evolution step 460: f(x)= 1.910712948742577
# differential_evolution step 461: f(x)= 1.910712948742577
# differential_evolution step 462: f(x)= 1.910712948742577
# differential_evolution step 463: f(x)= 1.9099506006782814
# differential_evolution step 464: f(x)= 1.9099506006782814
# differential_evolution step 465: f(x)= 1.9099506006782814
# differential_evolution step 466: f(x)= 1.9099506006782814
# differential_evolution step 467: f(x)= 1.9099506006782814
# differential_evolution step 468: f(x)= 1.9099506006782814
# differential_evolution step 469: f(x)= 1.9091198116121872
# differential_evolution step 470: f(x)= 1.9091198116121872
# differential_evolution step 471: f(x)= 1.9091198116121872
# differential_evolution step 472: f(x)= 1.9091198116121872
# differential_evolution step 473: f(x)= 1.9091198116121872
# differential_evolution step 474: f(x)= 1.9091198116121872
# differential_evolution step 475: f(x)= 1.9091198116121872
# differential_evolution step 476: f(x)= 1.9091198116121872
# differential_evolution step 477: f(x)= 1.9091198116121872
# differential_evolution step 478: f(x)= 1.9091198116121872
# differential_evolution step 479: f(x)= 1.9091198116121872
# differential_evolution step 480: f(x)= 1.9090731679324362
# differential_evolution step 481: f(x)= 1.9090731679324362
# differential_evolution step 482: f(x)= 1.9090731679324362
# differential_evolution step 483: f(x)= 1.9090731679324362
# differential_evolution step 484: f(x)= 1.9090731679324362
# differential_evolution step 485: f(x)= 1.9090731679324362
# differential_evolution step 486: f(x)= 1.9090731679324362
# differential_evolution step 487: f(x)= 1.9090731679324362
# differential_evolution step 488: f(x)= 1.9090731679324362
# differential_evolution step 489: f(x)= 1.9090731679324362
# differential_evolution step 490: f(x)= 1.9090731679324362
# differential_evolution step 491: f(x)= 1.9090731679324362
# differential_evolution step 492: f(x)= 1.9090731679324362
# differential_evolution step 493: f(x)= 1.9090731679324362
# differential_evolution step 494: f(x)= 1.9090731679324362
# differential_evolution step 495: f(x)= 1.9090731679324362
# differential_evolution step 496: f(x)= 1.9090731679324362
# differential_evolution step 497: f(x)= 1.9090731679324362
# differential_evolution step 498: f(x)= 1.9090731679324362
# differential_evolution step 499: f(x)= 1.9090731679324362
# differential_evolution step 500: f(x)= 1.9090731679324362
# differential_evolution step 501: f(x)= 1.9087967175278622
# differential_evolution step 502: f(x)= 1.9087967175278622
# differential_evolution step 503: f(x)= 1.9087967175278622
# differential_evolution step 504: f(x)= 1.9087945901364098
# differential_evolution step 505: f(x)= 1.9087945901364098
# differential_evolution step 506: f(x)= 1.9087945901364098
# differential_evolution step 507: f(x)= 1.9087945901364098
# differential_evolution step 508: f(x)= 1.9083928164213233
# differential_evolution step 509: f(x)= 1.9083928164213233
# differential_evolution step 510: f(x)= 1.9083928164213233
# differential_evolution step 511: f(x)= 1.9083928164213233
# differential_evolution step 512: f(x)= 1.9083928164213233
# differential_evolution step 513: f(x)= 1.9083928164213233
# differential_evolution step 514: f(x)= 1.9080071358617072
# differential_evolution step 515: f(x)= 1.9080071358617072
# differential_evolution step 516: f(x)= 1.9080071358617072
# differential_evolution step 517: f(x)= 1.9080071358617072
# differential_evolution step 518: f(x)= 1.9080071358617072
# differential_evolution step 519: f(x)= 1.9080071358617072
# differential_evolution step 520: f(x)= 1.9080071358617072
# differential_evolution step 521: f(x)= 1.9080071358617072
# differential_evolution step 522: f(x)= 1.9080071358617072
# differential_evolution step 523: f(x)= 1.9080071358617072
# differential_evolution step 524: f(x)= 1.9080071358617072
# differential_evolution step 525: f(x)= 1.9080071358617072
# differential_evolution step 526: f(x)= 1.9080071358617072
# differential_evolution step 527: f(x)= 1.9080071358617072
# differential_evolution step 528: f(x)= 1.9080071358617072
# differential_evolution step 529: f(x)= 1.9080071358617072
# differential_evolution step 530: f(x)= 1.9080071358617072
# differential_evolution step 531: f(x)= 1.9080071358617072
# differential_evolution step 532: f(x)= 1.9080071358617072
# differential_evolution step 533: f(x)= 1.9080071358617072
# differential_evolution step 534: f(x)= 1.9080071358617072
# differential_evolution step 535: f(x)= 1.9080071358617072
# differential_evolution step 536: f(x)= 1.9080071358617072
# differential_evolution step 537: f(x)= 1.9080071358617072
# differential_evolution step 538: f(x)= 1.9080071358617072
# differential_evolution step 539: f(x)= 1.9075119279792292
# differential_evolution step 540: f(x)= 1.9075119279792292
# differential_evolution step 541: f(x)= 1.9075119279792292
# differential_evolution step 542: f(x)= 1.9075119279792292
# differential_evolution step 543: f(x)= 1.9075119279792292
# differential_evolution step 544: f(x)= 1.9075119279792292
# differential_evolution step 545: f(x)= 1.9075119279792292
# differential_evolution step 546: f(x)= 1.9075119279792292
# differential_evolution step 547: f(x)= 1.9075119279792292
# differential_evolution step 548: f(x)= 1.9074511738785855
# differential_evolution step 549: f(x)= 1.9074511738785855
# differential_evolution step 550: f(x)= 1.9074511738785855
# differential_evolution step 551: f(x)= 1.9074511738785855
# differential_evolution step 552: f(x)= 1.9074511738785855
# differential_evolution step 553: f(x)= 1.9074511738785855
# differential_evolution step 554: f(x)= 1.9074511738785855
# differential_evolution step 555: f(x)= 1.9074511738785855
# differential_evolution step 556: f(x)= 1.9074511738785855
# differential_evolution step 557: f(x)= 1.9072811995093393
# differential_evolution step 558: f(x)= 1.9071348837599025
# differential_evolution step 559: f(x)= 1.9070632400834506
# differential_evolution step 560: f(x)= 1.9070632400834506
# differential_evolution step 561: f(x)= 1.9070632400834506
# differential_evolution step 562: f(x)= 1.9070632400834506
# differential_evolution step 563: f(x)= 1.9068841917707144
# differential_evolution step 564: f(x)= 1.9068841917707144
# differential_evolution step 565: f(x)= 1.9068841917707144
# differential_evolution step 566: f(x)= 1.9068841917707144
# differential_evolution step 567: f(x)= 1.9068841917707144
# differential_evolution step 568: f(x)= 1.9068841917707144
# differential_evolution step 569: f(x)= 1.9068841917707144
# differential_evolution step 570: f(x)= 1.9068841917707144
# differential_evolution step 571: f(x)= 1.9068063721320563
# differential_evolution step 572: f(x)= 1.9068063721320563
# differential_evolution step 573: f(x)= 1.90644627064548
# differential_evolution step 574: f(x)= 1.90644627064548
# differential_evolution step 575: f(x)= 1.90644627064548
# differential_evolution step 576: f(x)= 1.90644627064548
# differential_evolution step 577: f(x)= 1.90644627064548
# differential_evolution step 578: f(x)= 1.90644627064548
# differential_evolution step 579: f(x)= 1.9060291010139647
# differential_evolution step 580: f(x)= 1.906000826499573
# differential_evolution step 581: f(x)= 1.906000826499573
# differential_evolution step 582: f(x)= 1.906000826499573
# differential_evolution step 583: f(x)= 1.906000826499573
# differential_evolution step 584: f(x)= 1.9052881137353679
# differential_evolution step 585: f(x)= 1.9052881137353679
# differential_evolution step 586: f(x)= 1.9052881137353679
# differential_evolution step 587: f(x)= 1.905202516033848
# differential_evolution step 588: f(x)= 1.905202516033848
# differential_evolution step 589: f(x)= 1.905202516033848
# differential_evolution step 590: f(x)= 1.905202516033848
# differential_evolution step 591: f(x)= 1.905202516033848
# differential_evolution step 592: f(x)= 1.905202516033848
# differential_evolution step 593: f(x)= 1.905202516033848
# differential_evolution step 594: f(x)= 1.905202516033848
# differential_evolution step 595: f(x)= 1.9038561579596756
# differential_evolution step 596: f(x)= 1.9038561579596756
# differential_evolution step 597: f(x)= 1.903384276925873
# differential_evolution step 598: f(x)= 1.903384276925873
# differential_evolution step 599: f(x)= 1.903384276925873
# differential_evolution step 600: f(x)= 1.9024925583933125
# differential_evolution step 601: f(x)= 1.901641355968157
# differential_evolution step 602: f(x)= 1.901641355968157
# differential_evolution step 603: f(x)= 1.901641355968157
# differential_evolution step 604: f(x)= 1.9006919632725974
# differential_evolution step 605: f(x)= 1.9005682122317344
# differential_evolution step 606: f(x)= 1.9005682122317344
# differential_evolution step 607: f(x)= 1.9005682122317344
# differential_evolution step 608: f(x)= 1.8998013390983384
# differential_evolution step 609: f(x)= 1.8998013390983384
# differential_evolution step 610: f(x)= 1.8998013390983384
# differential_evolution step 611: f(x)= 1.8998013390983384
# differential_evolution step 612: f(x)= 1.8998013390983384
# differential_evolution step 613: f(x)= 1.8988586863927925
# differential_evolution step 614: f(x)= 1.8980893202201023
# differential_evolution step 615: f(x)= 1.8980893202201023
# differential_evolution step 616: f(x)= 1.8980893202201023
# differential_evolution step 617: f(x)= 1.8977808356728787
# differential_evolution step 618: f(x)= 1.8977808356728787
# differential_evolution step 619: f(x)= 1.8977808356728787
# differential_evolution step 620: f(x)= 1.8977808356728787
# differential_evolution step 621: f(x)= 1.8977808356728787
# differential_evolution step 622: f(x)= 1.8977808356728787
# differential_evolution step 623: f(x)= 1.8951825577429209
# differential_evolution step 624: f(x)= 1.8951825577429209
# differential_evolution step 625: f(x)= 1.8923507974582112
# differential_evolution step 626: f(x)= 1.8923507974582112
# differential_evolution step 627: f(x)= 1.8923507974582112
# differential_evolution step 628: f(x)= 1.8916422570052913
# differential_evolution step 629: f(x)= 1.8916422570052913
# differential_evolution step 630: f(x)= 1.8912027177266264
# differential_evolution step 631: f(x)= 1.8907303971744867
# differential_evolution step 632: f(x)= 1.8907303971744867
# differential_evolution step 633: f(x)= 1.8907303971744867
# differential_evolution step 634: f(x)= 1.8907303971744867
# differential_evolution step 635: f(x)= 1.8907303971744867
# differential_evolution step 636: f(x)= 1.8907303971744867
# differential_evolution step 637: f(x)= 1.8907303971744867
# differential_evolution step 638: f(x)= 1.8907303971744867
# differential_evolution step 639: f(x)= 1.8907303971744867
# differential_evolution step 640: f(x)= 1.8907303971744867
# differential_evolution step 641: f(x)= 1.8907303971744867
# differential_evolution step 642: f(x)= 1.8907303971744867
# differential_evolution step 643: f(x)= 1.8907303971744867
# differential_evolution step 644: f(x)= 1.8907303971744867
# differential_evolution step 645: f(x)= 1.8845526969713384
# differential_evolution step 646: f(x)= 1.8845526969713384
# differential_evolution step 647: f(x)= 1.8845526969713384
# differential_evolution step 648: f(x)= 1.8845526969713384
# differential_evolution step 649: f(x)= 1.8845526969713384
# differential_evolution step 650: f(x)= 1.8845526969713384
# differential_evolution step 651: f(x)= 1.8845526969713384
# differential_evolution step 652: f(x)= 1.8845526969713384
# differential_evolution step 653: f(x)= 1.8716102415713198
# differential_evolution step 654: f(x)= 1.8716102415713198
# differential_evolution step 655: f(x)= 1.8716102415713198
# differential_evolution step 656: f(x)= 1.8716102415713198
# differential_evolution step 657: f(x)= 1.8716102415713198
# differential_evolution step 658: f(x)= 1.8716102415713198
# differential_evolution step 659: f(x)= 1.8454586545464944
# differential_evolution step 660: f(x)= 1.8454586545464944
# differential_evolution step 661: f(x)= 1.8401947630922004
# differential_evolution step 662: f(x)= 1.8401947630922004
# differential_evolution step 663: f(x)= 1.8401947630922004
# differential_evolution step 664: f(x)= 1.8401947630922004
# differential_evolution step 665: f(x)= 1.8350912243905728
# differential_evolution step 666: f(x)= 1.834184928778801
# differential_evolution step 667: f(x)= 1.834184928778801
# differential_evolution step 668: f(x)= 1.834184928778801
# differential_evolution step 669: f(x)= 1.834184928778801
# differential_evolution step 670: f(x)= 1.825673042934137
# differential_evolution step 671: f(x)= 1.8211090994253267
# differential_evolution step 672: f(x)= 1.8211090994253267
# differential_evolution step 673: f(x)= 1.8211090994253267
# differential_evolution step 674: f(x)= 1.8211090994253267
# differential_evolution step 675: f(x)= 1.8179545184524168
# differential_evolution step 676: f(x)= 1.8179545184524168
# differential_evolution step 677: f(x)= 1.8098960331379748
# differential_evolution step 678: f(x)= 1.7927258872650707
# differential_evolution step 679: f(x)= 1.7915989068090434
# differential_evolution step 680: f(x)= 1.7913956850390462
# differential_evolution step 681: f(x)= 1.7913956850390462
# differential_evolution step 682: f(x)= 1.7913956850390462
# differential_evolution step 683: f(x)= 1.783357501602079
# differential_evolution step 684: f(x)= 1.783357501602079
# differential_evolution step 685: f(x)= 1.783357501602079
# differential_evolution step 686: f(x)= 1.783357501602079
# differential_evolution step 687: f(x)= 1.783357501602079
# differential_evolution step 688: f(x)= 1.783357501602079
# differential_evolution step 689: f(x)= 1.783357501602079
# differential_evolution step 690: f(x)= 1.783357501602079
# differential_evolution step 691: f(x)= 1.783357501602079
# differential_evolution step 692: f(x)= 1.783357501602079
# differential_evolution step 693: f(x)= 1.783357501602079
# differential_evolution step 694: f(x)= 1.783357501602079
# differential_evolution step 695: f(x)= 1.783357501602079
# differential_evolution step 696: f(x)= 1.783357501602079
# differential_evolution step 697: f(x)= 1.7788916497124108
# differential_evolution step 698: f(x)= 1.7788916497124108
# differential_evolution step 699: f(x)= 1.775194860343583
# differential_evolution step 700: f(x)= 1.775194860343583
# differential_evolution step 701: f(x)= 1.775194860343583
# differential_evolution step 702: f(x)= 1.775194860343583
# differential_evolution step 703: f(x)= 1.775194860343583
# differential_evolution step 704: f(x)= 1.775194860343583
# differential_evolution step 705: f(x)= 1.775194860343583
# differential_evolution step 706: f(x)= 1.775194860343583
# differential_evolution step 707: f(x)= 1.775194860343583
# differential_evolution step 708: f(x)= 1.775194860343583
# differential_evolution step 709: f(x)= 1.775194860343583
# differential_evolution step 710: f(x)= 1.775194860343583
# differential_evolution step 711: f(x)= 1.775194860343583
# differential_evolution step 712: f(x)= 1.775194860343583
# differential_evolution step 713: f(x)= 1.775194860343583
# differential_evolution step 714: f(x)= 1.775194860343583
# differential_evolution step 715: f(x)= 1.7454891846947693
# differential_evolution step 716: f(x)= 1.7454891846947693
# differential_evolution step 717: f(x)= 1.7269744797506081
# differential_evolution step 718: f(x)= 1.7269744797506081
# differential_evolution step 719: f(x)= 1.7269744797506081
# differential_evolution step 720: f(x)= 1.7269744797506081
# differential_evolution step 721: f(x)= 1.7269744797506081
# differential_evolution step 722: f(x)= 1.7269744797506081
# differential_evolution step 723: f(x)= 1.7269744797506081
# differential_evolution step 724: f(x)= 1.7269744797506081
# differential_evolution step 725: f(x)= 1.7269744797506081
# differential_evolution step 726: f(x)= 1.7269744797506081
# differential_evolution step 727: f(x)= 1.7269744797506081
# differential_evolution step 728: f(x)= 1.7269744797506081
# differential_evolution step 729: f(x)= 1.7269744797506081
# differential_evolution step 730: f(x)= 1.714311203960794
# differential_evolution step 731: f(x)= 1.714311203960794
# differential_evolution step 732: f(x)= 1.714311203960794
# differential_evolution step 733: f(x)= 1.714311203960794
# differential_evolution step 734: f(x)= 1.7114130458245318
# differential_evolution step 735: f(x)= 1.7114130458245318
# differential_evolution step 736: f(x)= 1.7114130458245318
# differential_evolution step 737: f(x)= 1.7036748737727594
# differential_evolution step 738: f(x)= 1.7036748737727594
# differential_evolution step 739: f(x)= 1.7036748737727594
# differential_evolution step 740: f(x)= 1.7036748737727594
# differential_evolution step 741: f(x)= 1.7036748737727594
# differential_evolution step 742: f(x)= 1.7036748737727594
# differential_evolution step 743: f(x)= 1.691371732496944
# differential_evolution step 744: f(x)= 1.691371732496944
# differential_evolution step 745: f(x)= 1.6874664177891132
# differential_evolution step 746: f(x)= 1.6874664177891132
# differential_evolution step 747: f(x)= 1.671701513814491
# differential_evolution step 748: f(x)= 1.671701513814491
# differential_evolution step 749: f(x)= 1.671701513814491
# differential_evolution step 750: f(x)= 1.671701513814491
# differential_evolution step 751: f(x)= 1.6642796878577861
# differential_evolution step 752: f(x)= 1.6589143702064708
# differential_evolution step 753: f(x)= 1.6589143702064708
# differential_evolution step 754: f(x)= 1.6589143702064708
# differential_evolution step 755: f(x)= 1.6589143702064708
# differential_evolution step 756: f(x)= 1.6447675433534459
# differential_evolution step 757: f(x)= 1.6447675433534459
# differential_evolution step 758: f(x)= 1.6447675433534459
# differential_evolution step 759: f(x)= 1.6447675433534459
# differential_evolution step 760: f(x)= 1.6447675433534459
# differential_evolution step 761: f(x)= 1.6447675433534459
# differential_evolution step 762: f(x)= 1.6447675433534459
# differential_evolution step 763: f(x)= 1.588210972165791
# differential_evolution step 764: f(x)= 1.588210972165791
# differential_evolution step 765: f(x)= 1.588210972165791
# differential_evolution step 766: f(x)= 1.588210972165791
# differential_evolution step 767: f(x)= 1.588210972165791
# differential_evolution step 768: f(x)= 1.588210972165791
# differential_evolution step 769: f(x)= 1.588210972165791
# differential_evolution step 770: f(x)= 1.588210972165791
# differential_evolution step 771: f(x)= 1.5874427389584518
# differential_evolution step 772: f(x)= 1.5874427389584518
# differential_evolution step 773: f(x)= 1.5823533026580667
# differential_evolution step 774: f(x)= 1.5672040650045518
# differential_evolution step 775: f(x)= 1.5314122822335443
# differential_evolution step 776: f(x)= 1.4753966457630683
# differential_evolution step 777: f(x)= 1.4753966457630683
# differential_evolution step 778: f(x)= 1.4753966457630683
# differential_evolution step 779: f(x)= 1.4693872342178917
# differential_evolution step 780: f(x)= 1.4693872342178917
# differential_evolution step 781: f(x)= 1.4693872342178917
# differential_evolution step 782: f(x)= 1.4693872342178917
# differential_evolution step 783: f(x)= 1.4693872342178917
# differential_evolution step 784: f(x)= 1.4693872342178917
# differential_evolution step 785: f(x)= 1.4693872342178917
# differential_evolution step 786: f(x)= 1.4693872342178917
# differential_evolution step 787: f(x)= 1.4693872342178917
# differential_evolution step 788: f(x)= 1.4693872342178917
# differential_evolution step 789: f(x)= 1.4693872342178917
# differential_evolution step 790: f(x)= 1.4693872342178917
# differential_evolution step 791: f(x)= 1.4693872342178917
# differential_evolution step 792: f(x)= 1.4693872342178917
# differential_evolution step 793: f(x)= 1.4693872342178917
# differential_evolution step 794: f(x)= 1.4693872342178917
# differential_evolution step 795: f(x)= 1.4693872342178917
# differential_evolution step 796: f(x)= 1.4693872342178917
# differential_evolution step 797: f(x)= 1.4693872342178917
# differential_evolution step 798: f(x)= 1.4693872342178917
# differential_evolution step 799: f(x)= 1.4693872342178917
# differential_evolution step 800: f(x)= 1.4693872342178917
# differential_evolution step 801: f(x)= 1.4693872342178917
# differential_evolution step 802: f(x)= 1.4693872342178917
# differential_evolution step 803: f(x)= 1.4693872342178917
# differential_evolution step 804: f(x)= 1.4493435793916984
# differential_evolution step 805: f(x)= 1.440092892694796
# differential_evolution step 806: f(x)= 1.440092892694796
# differential_evolution step 807: f(x)= 1.440092892694796
# differential_evolution step 808: f(x)= 1.4347739813436449
# differential_evolution step 809: f(x)= 1.4347739813436449
# differential_evolution step 810: f(x)= 1.4347739813436449
# differential_evolution step 811: f(x)= 1.4347739813436449
# differential_evolution step 812: f(x)= 1.4347739813436449
# differential_evolution step 813: f(x)= 1.429770359163444
# differential_evolution step 814: f(x)= 1.373660504248737
# differential_evolution step 815: f(x)= 1.373660504248737
# differential_evolution step 816: f(x)= 1.373660504248737
# differential_evolution step 817: f(x)= 1.373660504248737
# differential_evolution step 818: f(x)= 1.3718369374765207
# differential_evolution step 819: f(x)= 1.3718369374765207
# differential_evolution step 820: f(x)= 1.3718369374765207
# differential_evolution step 821: f(x)= 1.3718369374765207
# differential_evolution step 822: f(x)= 1.3718369374765207
# differential_evolution step 823: f(x)= 1.3718369374765207
# differential_evolution step 824: f(x)= 1.3601325009739722
# differential_evolution step 825: f(x)= 1.3601325009739722
# differential_evolution step 826: f(x)= 1.3601325009739722
# differential_evolution step 827: f(x)= 1.3601325009739722
# differential_evolution step 828: f(x)= 1.3601325009739722
# differential_evolution step 829: f(x)= 1.3566718862284788
# differential_evolution step 830: f(x)= 1.3566718862284788
# differential_evolution step 831: f(x)= 1.3566718862284788
# differential_evolution step 832: f(x)= 1.3566718862284788
# differential_evolution step 833: f(x)= 1.3566718862284788
# differential_evolution step 834: f(x)= 1.3566718862284788
# differential_evolution step 835: f(x)= 1.3566718862284788
# differential_evolution step 836: f(x)= 1.351172521802168
# differential_evolution step 837: f(x)= 1.351172521802168
# differential_evolution step 838: f(x)= 1.351172521802168
# differential_evolution step 839: f(x)= 1.3386316602776187
# differential_evolution step 840: f(x)= 1.3244575506327447
# differential_evolution step 841: f(x)= 1.3244575506327447
# differential_evolution step 842: f(x)= 1.3141602440437723
# differential_evolution step 843: f(x)= 1.3141602440437723
# differential_evolution step 844: f(x)= 1.3141602440437723
# differential_evolution step 845: f(x)= 1.3141602440437723
# differential_evolution step 846: f(x)= 1.3141602440437723
# differential_evolution step 847: f(x)= 1.3141602440437723
# differential_evolution step 848: f(x)= 1.3141602440437723
# differential_evolution step 849: f(x)= 1.3141602440437723
# differential_evolution step 850: f(x)= 1.3141602440437723
# differential_evolution step 851: f(x)= 1.3141602440437723
# differential_evolution step 852: f(x)= 1.3141602440437723
# differential_evolution step 853: f(x)= 1.3141602440437723
# differential_evolution step 854: f(x)= 1.3141602440437723
# differential_evolution step 855: f(x)= 1.3141602440437723
# differential_evolution step 856: f(x)= 1.3141602440437723
# differential_evolution step 857: f(x)= 1.3141602440437723
# differential_evolution step 858: f(x)= 1.3141602440437723
# differential_evolution step 859: f(x)= 1.3141602440437723
# differential_evolution step 860: f(x)= 1.3141602440437723
# differential_evolution step 861: f(x)= 1.3141602440437723
# differential_evolution step 862: f(x)= 1.3084843308854721
# differential_evolution step 863: f(x)= 1.3084843308854721
# differential_evolution step 864: f(x)= 1.3017929644292292
# differential_evolution step 865: f(x)= 1.3017929644292292
# differential_evolution step 866: f(x)= 1.300295047502542
# differential_evolution step 867: f(x)= 1.300295047502542
# differential_evolution step 868: f(x)= 1.300295047502542
# differential_evolution step 869: f(x)= 1.300295047502542
# differential_evolution step 870: f(x)= 1.300295047502542
# differential_evolution step 871: f(x)= 1.2855727595230144
# differential_evolution step 872: f(x)= 1.2855727595230144
# differential_evolution step 873: f(x)= 1.2855727595230144
# differential_evolution step 874: f(x)= 1.2855727595230144
# differential_evolution step 875: f(x)= 1.2855727595230144
# differential_evolution step 876: f(x)= 1.2855727595230144
# differential_evolution step 877: f(x)= 1.2855727595230144
# differential_evolution step 878: f(x)= 1.2855727595230144
# differential_evolution step 879: f(x)= 1.2855727595230144
# differential_evolution step 880: f(x)= 1.2855727595230144
# differential_evolution step 881: f(x)= 1.2855727595230144
# differential_evolution step 882: f(x)= 1.2855727595230144
# differential_evolution step 883: f(x)= 1.2803181389241929
# differential_evolution step 884: f(x)= 1.2803181389241929
# differential_evolution step 885: f(x)= 1.2803181389241929
# differential_evolution step 886: f(x)= 1.2803181389241929
# differential_evolution step 887: f(x)= 1.2803181389241929
# differential_evolution step 888: f(x)= 1.2803181389241929
# differential_evolution step 889: f(x)= 1.2803181389241929
# differential_evolution step 890: f(x)= 1.2803181389241929
# differential_evolution step 891: f(x)= 1.2785847974220608
# differential_evolution step 892: f(x)= 1.2785847974220608
# differential_evolution step 893: f(x)= 1.2709959721155386
# differential_evolution step 894: f(x)= 1.2709959721155386
# differential_evolution step 895: f(x)= 1.2709959721155386
# differential_evolution step 896: f(x)= 1.2709959721155386
# differential_evolution step 897: f(x)= 1.2553630498286406
# differential_evolution step 898: f(x)= 1.2553630498286406
# differential_evolution step 899: f(x)= 1.2553630498286406
# differential_evolution step 900: f(x)= 1.2553630498286406
# differential_evolution step 901: f(x)= 1.2553630498286406
# differential_evolution step 902: f(x)= 1.2553630498286406
# differential_evolution step 903: f(x)= 1.2553630498286406
# differential_evolution step 904: f(x)= 1.2553630498286406
# differential_evolution step 905: f(x)= 1.2553630498286406
# differential_evolution step 906: f(x)= 1.2553630498286406
# differential_evolution step 907: f(x)= 1.2553630498286406
# differential_evolution step 908: f(x)= 1.2553630498286406
# differential_evolution step 909: f(x)= 1.2553630498286406
# differential_evolution step 910: f(x)= 1.2553630498286406
# differential_evolution step 911: f(x)= 1.2553630498286406
# differential_evolution step 912: f(x)= 1.2553630498286406
# differential_evolution step 913: f(x)= 1.243189683589109
# differential_evolution step 914: f(x)= 1.243189683589109
# differential_evolution step 915: f(x)= 1.243189683589109
# differential_evolution step 916: f(x)= 1.243189683589109
# differential_evolution step 917: f(x)= 1.243189683589109
# differential_evolution step 918: f(x)= 1.243189683589109
# differential_evolution step 919: f(x)= 1.243189683589109
# differential_evolution step 920: f(x)= 1.243189683589109
# differential_evolution step 921: f(x)= 1.243189683589109
# differential_evolution step 922: f(x)= 1.243189683589109
# differential_evolution step 923: f(x)= 1.243189683589109
# differential_evolution step 924: f(x)= 1.242918934654866
# differential_evolution step 925: f(x)= 1.242918934654866
# differential_evolution step 926: f(x)= 1.242918934654866
# differential_evolution step 927: f(x)= 1.242918934654866
# differential_evolution step 928: f(x)= 1.242918934654866
# differential_evolution step 929: f(x)= 1.242918934654866
# differential_evolution step 930: f(x)= 1.242918934654866
# differential_evolution step 931: f(x)= 1.242918934654866
# differential_evolution step 932: f(x)= 1.2394322805030724
# differential_evolution step 933: f(x)= 1.2394322805030724
# differential_evolution step 934: f(x)= 1.2394322805030724
# differential_evolution step 935: f(x)= 1.2394322805030724
# differential_evolution step 936: f(x)= 1.2394322805030724
# differential_evolution step 937: f(x)= 1.2394322805030724
# differential_evolution step 938: f(x)= 1.2394322805030724
# differential_evolution step 939: f(x)= 1.2394322805030724
# differential_evolution step 940: f(x)= 1.2394322805030724
# differential_evolution step 941: f(x)= 1.2394322805030724
# differential_evolution step 942: f(x)= 1.2394322805030724
# differential_evolution step 943: f(x)= 1.2394322805030724
# differential_evolution step 944: f(x)= 1.2394322805030724
# differential_evolution step 945: f(x)= 1.2394322805030724
# differential_evolution step 946: f(x)= 1.2394322805030724
# differential_evolution step 947: f(x)= 1.2394322805030724
# differential_evolution step 948: f(x)= 1.2394322805030724
# differential_evolution step 949: f(x)= 1.2394322805030724
# differential_evolution step 950: f(x)= 1.2394322805030724
# differential_evolution step 951: f(x)= 1.2394322805030724
# differential_evolution step 952: f(x)= 1.2394322805030724
# differential_evolution step 953: f(x)= 1.2394322805030724
# differential_evolution step 954: f(x)= 1.2394322805030724
# differential_evolution step 955: f(x)= 1.2394322805030724
# differential_evolution step 956: f(x)= 1.2394322805030724
# differential_evolution step 957: f(x)= 1.2394322805030724
# differential_evolution step 958: f(x)= 1.2394322805030724
# differential_evolution step 959: f(x)= 1.2394322805030724
# differential_evolution step 960: f(x)= 1.2394322805030724
# differential_evolution step 961: f(x)= 1.2394322805030724
# differential_evolution step 962: f(x)= 1.2394322805030724
# differential_evolution step 963: f(x)= 1.2394322805030724
# differential_evolution step 964: f(x)= 1.2394322805030724
# differential_evolution step 965: f(x)= 1.2394322805030724
# differential_evolution step 966: f(x)= 1.2372272109293154
# differential_evolution step 967: f(x)= 1.2372272109293154
# differential_evolution step 968: f(x)= 1.2372272109293154
# differential_evolution step 969: f(x)= 1.2372272109293154
# differential_evolution step 970: f(x)= 1.2372272109293154
# differential_evolution step 971: f(x)= 1.2372272109293154
# differential_evolution step 972: f(x)= 1.2372272109293154
# differential_evolution step 973: f(x)= 1.2372272109293154
# differential_evolution step 974: f(x)= 1.2372272109293154
# differential_evolution step 975: f(x)= 1.2368928607113585
# differential_evolution step 976: f(x)= 1.2362308760296847
# differential_evolution step 977: f(x)= 1.2362308760296847
# differential_evolution step 978: f(x)= 1.2362308760296847
# differential_evolution step 979: f(x)= 1.2362308760296847
# differential_evolution step 980: f(x)= 1.2362308760296847
# differential_evolution step 981: f(x)= 1.2362308760296847
# differential_evolution step 982: f(x)= 1.2360734917040763
# differential_evolution step 983: f(x)= 1.2360734917040763
# differential_evolution step 984: f(x)= 1.2359853134242202
# differential_evolution step 985: f(x)= 1.2338559020868753
# differential_evolution step 986: f(x)= 1.2338559020868753
# differential_evolution step 987: f(x)= 1.2338559020868753
# differential_evolution step 988: f(x)= 1.2313270569019035
# differential_evolution step 989: f(x)= 1.2313270569019035
# differential_evolution step 990: f(x)= 1.2313270569019035
# differential_evolution step 991: f(x)= 1.2313270569019035
# differential_evolution step 992: f(x)= 1.2313270569019035
# differential_evolution step 993: f(x)= 1.2313270569019035
# differential_evolution step 994: f(x)= 1.2313270569019035
# differential_evolution step 995: f(x)= 1.2313270569019035
# differential_evolution step 996: f(x)= 1.2313270569019035
# differential_evolution step 997: f(x)= 1.2313270569019035
# differential_evolution step 998: f(x)= 1.2313270569019035
# differential_evolution step 999: f(x)= 1.2313270569019035
# differential_evolution step 1000: f(x)= 1.2313270569019035
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.1154, r_e=6.0131, n=1.0085, x_0=44.7757
# Sérsic 2: I_e=0.4775, r_e=24.8457, n=1.6379, x_0=51.5919
# Sérsic 3: I_e=3.4891, r_e=4.4626, n=0.6151, x_0=60.5733
# Chi quadro minimo: 1.22713501099234
# False

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = radial_profile_error_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, radial_profile_error_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.8597, r_e=9.3429, n=1.2585, x_0=44.9984
# Sérsic 2: I_e=0.1445, r_e=43.2604, n=2.3817, x_0=51.4837
# Sérsic 3: I_e=3.4272, r_e=4.9757, n=0.6532, x_0=60.3905
# [0.08835148 0.6164616  0.07009419 0.09653544 0.05726198 9.81887816
#  0.26506268 0.09035404 0.11354411 0.1359895  0.02484489 0.06966109]
# 12.142387056213666

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 1398.8617271160867
# differential_evolution step 2: f(x)= 431.58377523215665
# differential_evolution step 3: f(x)= 242.73215976066837
# differential_evolution step 4: f(x)= 179.49865467380414
# differential_evolution step 5: f(x)= 141.5965366531307
# differential_evolution step 6: f(x)= 141.5965366531307
# differential_evolution step 7: f(x)= 141.5965366531307
# differential_evolution step 8: f(x)= 141.5965366531307
# differential_evolution step 9: f(x)= 141.5965366531307
# differential_evolution step 10: f(x)= 141.5965366531307
# differential_evolution step 11: f(x)= 93.38912622871334
# differential_evolution step 12: f(x)= 93.38912622871334
# differential_evolution step 13: f(x)= 93.38912622871334
# differential_evolution step 14: f(x)= 93.38912622871334
# differential_evolution step 15: f(x)= 81.94652075961287
# differential_evolution step 16: f(x)= 77.41137791801793
# differential_evolution step 17: f(x)= 66.20031928120993
# differential_evolution step 18: f(x)= 66.20031928120993
# differential_evolution step 19: f(x)= 66.20031928120993
# differential_evolution step 20: f(x)= 66.20031928120993
# differential_evolution step 21: f(x)= 66.20031928120993
# differential_evolution step 22: f(x)= 25.535865397601654
# differential_evolution step 23: f(x)= 25.535865397601654
# differential_evolution step 24: f(x)= 25.535865397601654
# differential_evolution step 25: f(x)= 25.535865397601654
# differential_evolution step 26: f(x)= 25.535865397601654
# differential_evolution step 27: f(x)= 25.535865397601654
# differential_evolution step 28: f(x)= 25.535865397601654
# differential_evolution step 29: f(x)= 25.535865397601654
# differential_evolution step 30: f(x)= 19.817619231195046
# differential_evolution step 31: f(x)= 19.817619231195046
# differential_evolution step 32: f(x)= 19.817619231195046
# differential_evolution step 33: f(x)= 12.68597614049267
# differential_evolution step 34: f(x)= 12.68597614049267
# differential_evolution step 35: f(x)= 12.68597614049267
# differential_evolution step 36: f(x)= 12.68597614049267
# differential_evolution step 37: f(x)= 12.68597614049267
# differential_evolution step 38: f(x)= 12.68597614049267
# differential_evolution step 39: f(x)= 12.68597614049267
# differential_evolution step 40: f(x)= 12.68597614049267
# differential_evolution step 41: f(x)= 12.68597614049267
# differential_evolution step 42: f(x)= 12.68597614049267
# differential_evolution step 43: f(x)= 12.68597614049267
# differential_evolution step 44: f(x)= 11.726057235432561
# differential_evolution step 45: f(x)= 11.726057235432561
# differential_evolution step 46: f(x)= 11.726057235432561
# differential_evolution step 47: f(x)= 9.224042929932486
# differential_evolution step 48: f(x)= 9.224042929932486
# differential_evolution step 49: f(x)= 9.224042929932486
# differential_evolution step 50: f(x)= 9.224042929932486
# differential_evolution step 51: f(x)= 8.549880844816377
# differential_evolution step 52: f(x)= 8.549880844816377
# differential_evolution step 53: f(x)= 8.549880844816377
# differential_evolution step 54: f(x)= 8.549880844816377
# differential_evolution step 55: f(x)= 6.296352573675901
# differential_evolution step 56: f(x)= 6.296352573675901
# differential_evolution step 57: f(x)= 6.296352573675901
# differential_evolution step 58: f(x)= 6.296352573675901
# differential_evolution step 59: f(x)= 6.296352573675901
# differential_evolution step 60: f(x)= 6.296352573675901
# differential_evolution step 61: f(x)= 6.296352573675901
# differential_evolution step 62: f(x)= 6.010789587828683
# differential_evolution step 63: f(x)= 6.010789587828683
# differential_evolution step 64: f(x)= 6.010789587828683
# differential_evolution step 65: f(x)= 6.010789587828683
# differential_evolution step 66: f(x)= 6.010789587828683
# differential_evolution step 67: f(x)= 6.010789587828683
# differential_evolution step 68: f(x)= 6.010789587828683
# differential_evolution step 69: f(x)= 6.010789587828683
# differential_evolution step 70: f(x)= 5.185538650089624
# differential_evolution step 71: f(x)= 5.185538650089624
# differential_evolution step 72: f(x)= 5.185538650089624
# differential_evolution step 73: f(x)= 5.185538650089624
# differential_evolution step 74: f(x)= 5.185538650089624
# differential_evolution step 75: f(x)= 5.185538650089624
# differential_evolution step 76: f(x)= 5.185538650089624
# differential_evolution step 77: f(x)= 5.185538650089624
# differential_evolution step 78: f(x)= 5.185538650089624
# differential_evolution step 79: f(x)= 5.185538650089624
# differential_evolution step 80: f(x)= 5.185538650089624
# differential_evolution step 81: f(x)= 5.185538650089624
# differential_evolution step 82: f(x)= 5.185538650089624
# differential_evolution step 83: f(x)= 5.185538650089624
# differential_evolution step 84: f(x)= 5.185538650089624
# differential_evolution step 85: f(x)= 5.185538650089624
# differential_evolution step 86: f(x)= 5.175721734168939
# differential_evolution step 87: f(x)= 4.954776212095005
# differential_evolution step 88: f(x)= 4.954776212095005
# differential_evolution step 89: f(x)= 4.954776212095005
# differential_evolution step 90: f(x)= 4.889902258832305
# differential_evolution step 91: f(x)= 4.595447187423558
# differential_evolution step 92: f(x)= 4.595447187423558
# differential_evolution step 93: f(x)= 4.595447187423558
# differential_evolution step 94: f(x)= 4.595447187423558
# differential_evolution step 95: f(x)= 4.595447187423558
# differential_evolution step 96: f(x)= 4.595447187423558
# differential_evolution step 97: f(x)= 4.595447187423558
# differential_evolution step 98: f(x)= 4.595447187423558
# differential_evolution step 99: f(x)= 4.595447187423558
# differential_evolution step 100: f(x)= 4.282095265090129
# differential_evolution step 101: f(x)= 3.4314177829417982
# differential_evolution step 102: f(x)= 3.4314177829417982
# differential_evolution step 103: f(x)= 3.4314177829417982
# differential_evolution step 104: f(x)= 3.236654406164997
# differential_evolution step 105: f(x)= 3.236654406164997
# differential_evolution step 106: f(x)= 3.236654406164997
# differential_evolution step 107: f(x)= 2.948010301373604
# differential_evolution step 108: f(x)= 2.948010301373604
# differential_evolution step 109: f(x)= 2.948010301373604
# differential_evolution step 110: f(x)= 2.948010301373604
# differential_evolution step 111: f(x)= 2.948010301373604
# differential_evolution step 112: f(x)= 2.948010301373604
# differential_evolution step 113: f(x)= 2.658932450673251
# differential_evolution step 114: f(x)= 2.658932450673251
# differential_evolution step 115: f(x)= 2.658932450673251
# differential_evolution step 116: f(x)= 2.658932450673251
# differential_evolution step 117: f(x)= 2.658932450673251
# differential_evolution step 118: f(x)= 2.658932450673251
# differential_evolution step 119: f(x)= 2.658932450673251
# differential_evolution step 120: f(x)= 2.658932450673251
# differential_evolution step 121: f(x)= 2.658932450673251
# differential_evolution step 122: f(x)= 2.658932450673251
# differential_evolution step 123: f(x)= 2.658932450673251
# differential_evolution step 124: f(x)= 2.658932450673251
# differential_evolution step 125: f(x)= 2.658932450673251
# differential_evolution step 126: f(x)= 2.658932450673251
# differential_evolution step 127: f(x)= 2.658932450673251
# differential_evolution step 128: f(x)= 2.658932450673251
# differential_evolution step 129: f(x)= 2.658932450673251
# differential_evolution step 130: f(x)= 2.658932450673251
# differential_evolution step 131: f(x)= 2.658932450673251
# differential_evolution step 132: f(x)= 2.658932450673251
# differential_evolution step 133: f(x)= 2.658932450673251
# differential_evolution step 134: f(x)= 2.3031808490966648
# differential_evolution step 135: f(x)= 2.3031808490966648
# differential_evolution step 136: f(x)= 2.3031808490966648
# differential_evolution step 137: f(x)= 2.3031808490966648
# differential_evolution step 138: f(x)= 2.3031808490966648
# differential_evolution step 139: f(x)= 2.3031808490966648
# differential_evolution step 140: f(x)= 2.3031808490966648
# differential_evolution step 141: f(x)= 2.3031808490966648
# differential_evolution step 142: f(x)= 2.3031808490966648
# differential_evolution step 143: f(x)= 2.3031808490966648
# differential_evolution step 144: f(x)= 2.3031808490966648
# differential_evolution step 145: f(x)= 2.3031808490966648
# differential_evolution step 146: f(x)= 2.3031808490966648
# differential_evolution step 147: f(x)= 2.3031808490966648
# differential_evolution step 148: f(x)= 2.3031808490966648
# differential_evolution step 149: f(x)= 2.1989806706301938
# differential_evolution step 150: f(x)= 2.1989806706301938
# differential_evolution step 151: f(x)= 2.188452503341746
# differential_evolution step 152: f(x)= 2.188452503341746
# differential_evolution step 153: f(x)= 2.188452503341746
# differential_evolution step 154: f(x)= 2.188452503341746
# differential_evolution step 155: f(x)= 2.18458251264962
# differential_evolution step 156: f(x)= 2.18458251264962
# differential_evolution step 157: f(x)= 2.18458251264962
# differential_evolution step 158: f(x)= 2.1411633744810152
# differential_evolution step 159: f(x)= 2.1370483685434847
# differential_evolution step 160: f(x)= 2.061679357451063
# differential_evolution step 161: f(x)= 2.061679357451063
# differential_evolution step 162: f(x)= 1.9534504683741867
# differential_evolution step 163: f(x)= 1.9094508615323342
# differential_evolution step 164: f(x)= 1.9094508615323342
# differential_evolution step 165: f(x)= 1.9094508615323342
# differential_evolution step 166: f(x)= 1.7780796509606156
# differential_evolution step 167: f(x)= 1.7780796509606156
# differential_evolution step 168: f(x)= 1.7780796509606156
# differential_evolution step 169: f(x)= 1.7780796509606156
# differential_evolution step 170: f(x)= 1.7780796509606156
# differential_evolution step 171: f(x)= 1.7780796509606156
# differential_evolution step 172: f(x)= 1.7780796509606156
# differential_evolution step 173: f(x)= 1.7780796509606156
# differential_evolution step 174: f(x)= 1.7199785022050051
# differential_evolution step 175: f(x)= 1.7199785022050051
# differential_evolution step 176: f(x)= 1.7199785022050051
# differential_evolution step 177: f(x)= 1.7199785022050051
# differential_evolution step 178: f(x)= 1.7199785022050051
# differential_evolution step 179: f(x)= 1.7199785022050051
# differential_evolution step 180: f(x)= 1.7199785022050051
# differential_evolution step 181: f(x)= 1.7199785022050051
# differential_evolution step 182: f(x)= 1.7199785022050051
# differential_evolution step 183: f(x)= 1.7199785022050051
# differential_evolution step 184: f(x)= 1.7094349212611095
# differential_evolution step 185: f(x)= 1.7094349212611095
# differential_evolution step 186: f(x)= 1.7094349212611095
# differential_evolution step 187: f(x)= 1.7094349212611095
# differential_evolution step 188: f(x)= 1.7094349212611095
# differential_evolution step 189: f(x)= 1.7094349212611095
# differential_evolution step 190: f(x)= 1.6235497133229997
# differential_evolution step 191: f(x)= 1.6235497133229997
# differential_evolution step 192: f(x)= 1.6235497133229997
# differential_evolution step 193: f(x)= 1.6235497133229997
# differential_evolution step 194: f(x)= 1.6235497133229997
# differential_evolution step 195: f(x)= 1.6235497133229997
# differential_evolution step 196: f(x)= 1.6235497133229997
# differential_evolution step 197: f(x)= 1.6235497133229997
# differential_evolution step 198: f(x)= 1.6235497133229997
# differential_evolution step 199: f(x)= 1.6235497133229997
# differential_evolution step 200: f(x)= 1.6235497133229997
# differential_evolution step 201: f(x)= 1.6235497133229997
# differential_evolution step 202: f(x)= 1.6235497133229997
# differential_evolution step 203: f(x)= 1.6235497133229997
# differential_evolution step 204: f(x)= 1.594504228523097
# differential_evolution step 205: f(x)= 1.594504228523097
# differential_evolution step 206: f(x)= 1.594504228523097
# differential_evolution step 207: f(x)= 1.594504228523097
# differential_evolution step 208: f(x)= 1.594504228523097
# differential_evolution step 209: f(x)= 1.594504228523097
# differential_evolution step 210: f(x)= 1.594504228523097
# differential_evolution step 211: f(x)= 1.594504228523097
# differential_evolution step 212: f(x)= 1.5933799529768116
# differential_evolution step 213: f(x)= 1.5933799529768116
# differential_evolution step 214: f(x)= 1.5933799529768116
# differential_evolution step 215: f(x)= 1.5933799529768116
# differential_evolution step 216: f(x)= 1.5933799529768116
# differential_evolution step 217: f(x)= 1.5933799529768116
# differential_evolution step 218: f(x)= 1.5845166580752963
# differential_evolution step 219: f(x)= 1.5845166580752963
# differential_evolution step 220: f(x)= 1.5845166580752963
# differential_evolution step 221: f(x)= 1.5845166580752963
# differential_evolution step 222: f(x)= 1.5845166580752963
# differential_evolution step 223: f(x)= 1.5845166580752963
# differential_evolution step 224: f(x)= 1.5845166580752963
# differential_evolution step 225: f(x)= 1.57223956645316
# differential_evolution step 226: f(x)= 1.57223956645316
# differential_evolution step 227: f(x)= 1.57223956645316
# differential_evolution step 228: f(x)= 1.57223956645316
# differential_evolution step 229: f(x)= 1.5639236481526035
# differential_evolution step 230: f(x)= 1.5639236481526035
# differential_evolution step 231: f(x)= 1.5639236481526035
# differential_evolution step 232: f(x)= 1.5639236481526035
# differential_evolution step 233: f(x)= 1.5639236481526035
# differential_evolution step 234: f(x)= 1.5639236481526035
# differential_evolution step 235: f(x)= 1.5639236481526035
# differential_evolution step 236: f(x)= 1.5639236481526035
# differential_evolution step 237: f(x)= 1.5639236481526035
# differential_evolution step 238: f(x)= 1.5639236481526035
# differential_evolution step 239: f(x)= 1.5639236481526035
# differential_evolution step 240: f(x)= 1.5639236481526035
# differential_evolution step 241: f(x)= 1.5639236481526035
# differential_evolution step 242: f(x)= 1.5639236481526035
# differential_evolution step 243: f(x)= 1.5639236481526035
# differential_evolution step 244: f(x)= 1.5639236481526035
# differential_evolution step 245: f(x)= 1.5639236481526035
# differential_evolution step 246: f(x)= 1.5639236481526035
# differential_evolution step 247: f(x)= 1.5639236481526035
# differential_evolution step 248: f(x)= 1.5639236481526035
# differential_evolution step 249: f(x)= 1.5633401245821432
# differential_evolution step 250: f(x)= 1.5633401245821432
# differential_evolution step 251: f(x)= 1.5633401245821432
# differential_evolution step 252: f(x)= 1.5633401245821432
# differential_evolution step 253: f(x)= 1.5633401245821432
# differential_evolution step 254: f(x)= 1.5633401245821432
# differential_evolution step 255: f(x)= 1.5627624415448327
# differential_evolution step 256: f(x)= 1.5627624415448327
# differential_evolution step 257: f(x)= 1.5627624415448327
# differential_evolution step 258: f(x)= 1.5627624415448327
# differential_evolution step 259: f(x)= 1.5627624415448327
# differential_evolution step 260: f(x)= 1.5593366972640443
# differential_evolution step 261: f(x)= 1.5593366972640443
# differential_evolution step 262: f(x)= 1.5593366972640443
# differential_evolution step 263: f(x)= 1.5593366972640443
# differential_evolution step 264: f(x)= 1.5593366972640443
# differential_evolution step 265: f(x)= 1.5593366972640443
# differential_evolution step 266: f(x)= 1.5593366972640443
# differential_evolution step 267: f(x)= 1.5593366972640443
# differential_evolution step 268: f(x)= 1.5593366972640443
# differential_evolution step 269: f(x)= 1.5593366972640443
# differential_evolution step 270: f(x)= 1.558260926557853
# differential_evolution step 271: f(x)= 1.558260926557853
# differential_evolution step 272: f(x)= 1.558260926557853
# differential_evolution step 273: f(x)= 1.558260926557853
# differential_evolution step 274: f(x)= 1.558260926557853
# differential_evolution step 275: f(x)= 1.558260926557853
# differential_evolution step 276: f(x)= 1.558260926557853
# differential_evolution step 277: f(x)= 1.558260926557853
# differential_evolution step 278: f(x)= 1.558260926557853
# differential_evolution step 279: f(x)= 1.558260926557853
# differential_evolution step 280: f(x)= 1.5545701181950813
# differential_evolution step 281: f(x)= 1.5545701181950813
# differential_evolution step 282: f(x)= 1.552876532865418
# differential_evolution step 283: f(x)= 1.552876532865418
# differential_evolution step 284: f(x)= 1.552876532865418
# differential_evolution step 285: f(x)= 1.552876532865418
# differential_evolution step 286: f(x)= 1.5520388415601576
# differential_evolution step 287: f(x)= 1.5520388415601576
# differential_evolution step 288: f(x)= 1.5520388415601576
# differential_evolution step 289: f(x)= 1.5520388415601576
# differential_evolution step 290: f(x)= 1.5520388415601576
# differential_evolution step 291: f(x)= 1.5520388415601576
# differential_evolution step 292: f(x)= 1.5520388415601576
# differential_evolution step 293: f(x)= 1.5520388415601576
# differential_evolution step 294: f(x)= 1.5520388415601576
# differential_evolution step 295: f(x)= 1.5520388415601576
# differential_evolution step 296: f(x)= 1.5512701253531258
# differential_evolution step 297: f(x)= 1.5512701253531258
# differential_evolution step 298: f(x)= 1.5512701253531258
# differential_evolution step 299: f(x)= 1.5512701253531258
# differential_evolution step 300: f(x)= 1.5512701253531258
# differential_evolution step 301: f(x)= 1.5512701253531258
# differential_evolution step 302: f(x)= 1.5512701253531258
# differential_evolution step 303: f(x)= 1.5512701253531258
# differential_evolution step 304: f(x)= 1.5512701253531258
# differential_evolution step 305: f(x)= 1.5512701253531258
# differential_evolution step 306: f(x)= 1.5512701253531258
# differential_evolution step 307: f(x)= 1.5512701253531258
# differential_evolution step 308: f(x)= 1.5512701253531258
# differential_evolution step 309: f(x)= 1.5512701253531258
# differential_evolution step 310: f(x)= 1.5512701253531258
# differential_evolution step 311: f(x)= 1.5471099987278754
# differential_evolution step 312: f(x)= 1.5471099987278754
# differential_evolution step 313: f(x)= 1.5471099987278754
# differential_evolution step 314: f(x)= 1.5471099987278754
# differential_evolution step 315: f(x)= 1.5471099987278754
# differential_evolution step 316: f(x)= 1.5451561906516609
# differential_evolution step 317: f(x)= 1.5451561906516609
# differential_evolution step 318: f(x)= 1.5451561906516609
# differential_evolution step 319: f(x)= 1.5451561906516609
# differential_evolution step 320: f(x)= 1.5451561906516609
# differential_evolution step 321: f(x)= 1.5451561906516609
# differential_evolution step 322: f(x)= 1.5451561906516609
# differential_evolution step 323: f(x)= 1.5451561906516609
# differential_evolution step 324: f(x)= 1.5451561906516609
# differential_evolution step 325: f(x)= 1.5451561906516609
# differential_evolution step 326: f(x)= 1.5451561906516609
# differential_evolution step 327: f(x)= 1.5451561906516609
# differential_evolution step 328: f(x)= 1.5451561906516609
# differential_evolution step 329: f(x)= 1.5437419951778013
# differential_evolution step 330: f(x)= 1.5437419951778013
# differential_evolution step 331: f(x)= 1.5437419951778013
# differential_evolution step 332: f(x)= 1.5437419951778013
# differential_evolution step 333: f(x)= 1.5437419951778013
# differential_evolution step 334: f(x)= 1.5437419951778013
# differential_evolution step 335: f(x)= 1.5437419951778013
# differential_evolution step 336: f(x)= 1.5437419951778013
# differential_evolution step 337: f(x)= 1.5437419951778013
# differential_evolution step 338: f(x)= 1.5437419951778013
# differential_evolution step 339: f(x)= 1.5437419951778013
# differential_evolution step 340: f(x)= 1.5437419951778013
# differential_evolution step 341: f(x)= 1.5437419951778013
# differential_evolution step 342: f(x)= 1.5437419951778013
# differential_evolution step 343: f(x)= 1.5437419951778013
# differential_evolution step 344: f(x)= 1.5437419951778013
# differential_evolution step 345: f(x)= 1.5437419951778013
# differential_evolution step 346: f(x)= 1.5437419951778013
# differential_evolution step 347: f(x)= 1.5437419951778013
# differential_evolution step 348: f(x)= 1.5437419951778013
# differential_evolution step 349: f(x)= 1.5437419951778013
# differential_evolution step 350: f(x)= 1.5437419951778013
# differential_evolution step 351: f(x)= 1.5437419951778013
# differential_evolution step 352: f(x)= 1.5437419951778013
# differential_evolution step 353: f(x)= 1.5437419951778013
# differential_evolution step 354: f(x)= 1.5437419951778013
# differential_evolution step 355: f(x)= 1.5437419951778013
# differential_evolution step 356: f(x)= 1.5437419951778013
# differential_evolution step 357: f(x)= 1.5437419951778013
# differential_evolution step 358: f(x)= 1.5437419951778013
# differential_evolution step 359: f(x)= 1.541860081382917
# differential_evolution step 360: f(x)= 1.541860081382917
# differential_evolution step 361: f(x)= 1.541860081382917
# differential_evolution step 362: f(x)= 1.541860081382917
# differential_evolution step 363: f(x)= 1.541860081382917
# differential_evolution step 364: f(x)= 1.541860081382917
# differential_evolution step 365: f(x)= 1.541860081382917
# differential_evolution step 366: f(x)= 1.541860081382917
# differential_evolution step 367: f(x)= 1.541860081382917
# differential_evolution step 368: f(x)= 1.541860081382917
# differential_evolution step 369: f(x)= 1.541860081382917
# differential_evolution step 370: f(x)= 1.541860081382917
# differential_evolution step 371: f(x)= 1.541860081382917
# differential_evolution step 372: f(x)= 1.541860081382917
# differential_evolution step 373: f(x)= 1.541860081382917
# differential_evolution step 374: f(x)= 1.541860081382917
# differential_evolution step 375: f(x)= 1.541860081382917
# differential_evolution step 376: f(x)= 1.541860081382917
# differential_evolution step 377: f(x)= 1.541860081382917
# differential_evolution step 378: f(x)= 1.541860081382917
# differential_evolution step 379: f(x)= 1.541860081382917
# differential_evolution step 380: f(x)= 1.541860081382917
# differential_evolution step 381: f(x)= 1.541860081382917
# differential_evolution step 382: f(x)= 1.541860081382917
# differential_evolution step 383: f(x)= 1.541860081382917
# differential_evolution step 384: f(x)= 1.541860081382917
# differential_evolution step 385: f(x)= 1.541860081382917
# differential_evolution step 386: f(x)= 1.541860081382917
# differential_evolution step 387: f(x)= 1.541860081382917
# differential_evolution step 388: f(x)= 1.541860081382917
# differential_evolution step 389: f(x)= 1.541860081382917
# differential_evolution step 390: f(x)= 1.541860081382917
# differential_evolution step 391: f(x)= 1.541860081382917
# differential_evolution step 392: f(x)= 1.541860081382917
# differential_evolution step 393: f(x)= 1.541860081382917
# differential_evolution step 394: f(x)= 1.541860081382917
# differential_evolution step 395: f(x)= 1.541860081382917
# differential_evolution step 396: f(x)= 1.541860081382917
# differential_evolution step 397: f(x)= 1.541860081382917
# differential_evolution step 398: f(x)= 1.541860081382917
# differential_evolution step 399: f(x)= 1.541860081382917
# differential_evolution step 400: f(x)= 1.541860081382917
# differential_evolution step 401: f(x)= 1.5414434788947462
# differential_evolution step 402: f(x)= 1.5414434788947462
# differential_evolution step 403: f(x)= 1.5414434788947462
# differential_evolution step 404: f(x)= 1.5414434788947462
# differential_evolution step 405: f(x)= 1.5414434788947462
# differential_evolution step 406: f(x)= 1.5414434788947462
# differential_evolution step 407: f(x)= 1.5410995987791272
# differential_evolution step 408: f(x)= 1.5410995987791272
# differential_evolution step 409: f(x)= 1.5410995987791272
# differential_evolution step 410: f(x)= 1.5410995987791272
# differential_evolution step 411: f(x)= 1.5410995987791272
# differential_evolution step 412: f(x)= 1.5410995987791272
# differential_evolution step 413: f(x)= 1.5410995987791272
# differential_evolution step 414: f(x)= 1.5410995987791272
# differential_evolution step 415: f(x)= 1.5410995987791272
# differential_evolution step 416: f(x)= 1.5410995987791272
# differential_evolution step 417: f(x)= 1.5410995987791272
# differential_evolution step 418: f(x)= 1.5410995987791272
# differential_evolution step 419: f(x)= 1.5410995987791272
# differential_evolution step 420: f(x)= 1.5410995987791272
# differential_evolution step 421: f(x)= 1.5410995987791272
# differential_evolution step 422: f(x)= 1.5410995987791272
# differential_evolution step 423: f(x)= 1.5410995987791272
# differential_evolution step 424: f(x)= 1.5410995987791272
# differential_evolution step 425: f(x)= 1.5410995987791272
# differential_evolution step 426: f(x)= 1.5410995987791272
# differential_evolution step 427: f(x)= 1.5410995987791272
# differential_evolution step 428: f(x)= 1.5410995987791272
# differential_evolution step 429: f(x)= 1.5410995987791272
# differential_evolution step 430: f(x)= 1.5410995987791272
# differential_evolution step 431: f(x)= 1.5410995987791272
# differential_evolution step 432: f(x)= 1.5410995987791272
# differential_evolution step 433: f(x)= 1.5410995987791272
# differential_evolution step 434: f(x)= 1.5410995987791272
# differential_evolution step 435: f(x)= 1.5410995987791272
# differential_evolution step 436: f(x)= 1.5410995987791272
# differential_evolution step 437: f(x)= 1.5410995987791272
# differential_evolution step 438: f(x)= 1.5410995987791272
# differential_evolution step 439: f(x)= 1.5410995987791272
# differential_evolution step 440: f(x)= 1.5410553017537438
# differential_evolution step 441: f(x)= 1.5410553017537438
# differential_evolution step 442: f(x)= 1.5410553017537438
# differential_evolution step 443: f(x)= 1.5410553017537438
# differential_evolution step 444: f(x)= 1.5410553017537438
# differential_evolution step 445: f(x)= 1.5410553017537438
# differential_evolution step 446: f(x)= 1.5409640919473804
# differential_evolution step 447: f(x)= 1.5409640919473804
# differential_evolution step 448: f(x)= 1.5407949324511934
# differential_evolution step 449: f(x)= 1.5407949324511934
# differential_evolution step 450: f(x)= 1.5407949324511934
# differential_evolution step 451: f(x)= 1.5407949324511934
# differential_evolution step 452: f(x)= 1.5407949324511934
# differential_evolution step 453: f(x)= 1.5407949324511934
# differential_evolution step 454: f(x)= 1.5407949324511934
# differential_evolution step 455: f(x)= 1.5407949324511934
# differential_evolution step 456: f(x)= 1.5406318578872977
# differential_evolution step 457: f(x)= 1.5406310464468969
# differential_evolution step 458: f(x)= 1.5406310464468969
# differential_evolution step 459: f(x)= 1.5398174121972736
# differential_evolution step 460: f(x)= 1.5398174121972736
# differential_evolution step 461: f(x)= 1.5398174121972736
# differential_evolution step 462: f(x)= 1.5398174121972736
# differential_evolution step 463: f(x)= 1.5398174121972736
# differential_evolution step 464: f(x)= 1.5398174121972736
# differential_evolution step 465: f(x)= 1.5398174121972736
# differential_evolution step 466: f(x)= 1.5398174121972736
# differential_evolution step 467: f(x)= 1.5390441677067142
# differential_evolution step 468: f(x)= 1.5390441677067142
# differential_evolution step 469: f(x)= 1.5390441677067142
# differential_evolution step 470: f(x)= 1.5390441677067142
# differential_evolution step 471: f(x)= 1.5390441677067142
# differential_evolution step 472: f(x)= 1.5390441677067142
# differential_evolution step 473: f(x)= 1.5380654306417523
# differential_evolution step 474: f(x)= 1.5380654306417523
# differential_evolution step 475: f(x)= 1.5376667926614305
# differential_evolution step 476: f(x)= 1.5376667926614305
# differential_evolution step 477: f(x)= 1.5376667926614305
# differential_evolution step 478: f(x)= 1.5376667926614305
# differential_evolution step 479: f(x)= 1.5376667926614305
# differential_evolution step 480: f(x)= 1.537267152430236
# differential_evolution step 481: f(x)= 1.537267152430236
# differential_evolution step 482: f(x)= 1.537260833161583
# differential_evolution step 483: f(x)= 1.5368940926424492
# differential_evolution step 484: f(x)= 1.5368940926424492
# differential_evolution step 485: f(x)= 1.5368940926424492
# differential_evolution step 486: f(x)= 1.5368940926424492
# differential_evolution step 487: f(x)= 1.5368940926424492
# differential_evolution step 488: f(x)= 1.5368940926424492
# differential_evolution step 489: f(x)= 1.5368940926424492
# differential_evolution step 490: f(x)= 1.5368940926424492
# differential_evolution step 491: f(x)= 1.5368940926424492
# differential_evolution step 492: f(x)= 1.5368940926424492
# differential_evolution step 493: f(x)= 1.5368940926424492
# differential_evolution step 494: f(x)= 1.5368940926424492
# differential_evolution step 495: f(x)= 1.5368940926424492
# differential_evolution step 496: f(x)= 1.5368940926424492
# differential_evolution step 497: f(x)= 1.5368940926424492
# differential_evolution step 498: f(x)= 1.5368940926424492
# differential_evolution step 499: f(x)= 1.536117872911859
# differential_evolution step 500: f(x)= 1.536117872911859
# differential_evolution step 501: f(x)= 1.536117872911859
# differential_evolution step 502: f(x)= 1.536117872911859
# differential_evolution step 503: f(x)= 1.536117872911859
# differential_evolution step 504: f(x)= 1.536117872911859
# differential_evolution step 505: f(x)= 1.536117872911859
# differential_evolution step 506: f(x)= 1.536024041264098
# differential_evolution step 507: f(x)= 1.536024041264098
# differential_evolution step 508: f(x)= 1.536024041264098
# differential_evolution step 509: f(x)= 1.536024041264098
# differential_evolution step 510: f(x)= 1.5355792865406395
# differential_evolution step 511: f(x)= 1.5355792865406395
# differential_evolution step 512: f(x)= 1.5355792865406395
# differential_evolution step 513: f(x)= 1.5355792865406395
# differential_evolution step 514: f(x)= 1.5355792865406395
# differential_evolution step 515: f(x)= 1.5355792865406395
# differential_evolution step 516: f(x)= 1.5355792865406395
# differential_evolution step 517: f(x)= 1.5355792865406395
# differential_evolution step 518: f(x)= 1.5355792865406395
# differential_evolution step 519: f(x)= 1.5355792865406395
# differential_evolution step 520: f(x)= 1.5355792865406395
# differential_evolution step 521: f(x)= 1.5355792865406395
# differential_evolution step 522: f(x)= 1.5355792865406395
# differential_evolution step 523: f(x)= 1.5345224721858157
# differential_evolution step 524: f(x)= 1.5345224721858157
# differential_evolution step 525: f(x)= 1.5345224721858157
# differential_evolution step 526: f(x)= 1.5345224721858157
# differential_evolution step 527: f(x)= 1.5345224721858157
# differential_evolution step 528: f(x)= 1.5345224721858157
# differential_evolution step 529: f(x)= 1.5345224721858157
# differential_evolution step 530: f(x)= 1.5345224721858157
# differential_evolution step 531: f(x)= 1.5345224721858157
# differential_evolution step 532: f(x)= 1.5345224721858157
# differential_evolution step 533: f(x)= 1.5345224721858157
# differential_evolution step 534: f(x)= 1.5345224721858157
# differential_evolution step 535: f(x)= 1.5345224721858157
# differential_evolution step 536: f(x)= 1.5345224721858157
# differential_evolution step 537: f(x)= 1.5345224721858157
# differential_evolution step 538: f(x)= 1.5345224721858157
# differential_evolution step 539: f(x)= 1.5345224721858157
# differential_evolution step 540: f(x)= 1.5345224721858157
# differential_evolution step 541: f(x)= 1.5345224721858157
# differential_evolution step 542: f(x)= 1.5345224721858157
# differential_evolution step 543: f(x)= 1.5345224721858157
# differential_evolution step 544: f(x)= 1.5345224721858157
# differential_evolution step 545: f(x)= 1.5345224721858157
# differential_evolution step 546: f(x)= 1.5345224721858157
# differential_evolution step 547: f(x)= 1.5345224721858157
# differential_evolution step 548: f(x)= 1.5345224721858157
# differential_evolution step 549: f(x)= 1.5345224721858157
# differential_evolution step 550: f(x)= 1.5345224721858157
# differential_evolution step 551: f(x)= 1.5345224721858157
# differential_evolution step 552: f(x)= 1.5345224721858157
# differential_evolution step 553: f(x)= 1.5345224721858157
# differential_evolution step 554: f(x)= 1.5345224721858157
# differential_evolution step 555: f(x)= 1.5345224721858157
# differential_evolution step 556: f(x)= 1.5345224721858157
# differential_evolution step 557: f(x)= 1.5345224721858157
# differential_evolution step 558: f(x)= 1.5345224721858157
# differential_evolution step 559: f(x)= 1.5345224721858157
# differential_evolution step 560: f(x)= 1.5345224721858157
# differential_evolution step 561: f(x)= 1.5345224721858157
# differential_evolution step 562: f(x)= 1.5345224721858157
# differential_evolution step 563: f(x)= 1.5345224721858157
# differential_evolution step 564: f(x)= 1.5345224721858157
# differential_evolution step 565: f(x)= 1.5345224721858157
# differential_evolution step 566: f(x)= 1.5345224721858157
# differential_evolution step 567: f(x)= 1.5345224721858157
# differential_evolution step 568: f(x)= 1.5345224721858157
# differential_evolution step 569: f(x)= 1.5345224721858157
# differential_evolution step 570: f(x)= 1.5345224721858157
# differential_evolution step 571: f(x)= 1.5345224721858157
# differential_evolution step 572: f(x)= 1.5343251276045637
# differential_evolution step 573: f(x)= 1.5343251276045637
# differential_evolution step 574: f(x)= 1.5343251276045637
# differential_evolution step 575: f(x)= 1.5343251276045637
# differential_evolution step 576: f(x)= 1.5343251276045637
# differential_evolution step 577: f(x)= 1.5343251276045637
# differential_evolution step 578: f(x)= 1.5343251276045637
# differential_evolution step 579: f(x)= 1.5343251276045637
# differential_evolution step 580: f(x)= 1.5343251276045637
# differential_evolution step 581: f(x)= 1.5343251276045637
# differential_evolution step 582: f(x)= 1.5334743087794591
# differential_evolution step 583: f(x)= 1.5334743087794591
# differential_evolution step 584: f(x)= 1.5334743087794591
# differential_evolution step 585: f(x)= 1.5334743087794591
# differential_evolution step 586: f(x)= 1.5334743087794591
# differential_evolution step 587: f(x)= 1.5334743087794591
# differential_evolution step 588: f(x)= 1.5334743087794591
# differential_evolution step 589: f(x)= 1.5334743087794591
# differential_evolution step 590: f(x)= 1.5334743087794591
# differential_evolution step 591: f(x)= 1.5334743087794591
# differential_evolution step 592: f(x)= 1.5334743087794591
# differential_evolution step 593: f(x)= 1.5334743087794591
# differential_evolution step 594: f(x)= 1.5334743087794591
# differential_evolution step 595: f(x)= 1.5334743087794591
# differential_evolution step 596: f(x)= 1.5334743087794591
# differential_evolution step 597: f(x)= 1.5334743087794591
# differential_evolution step 598: f(x)= 1.5334743087794591
# differential_evolution step 599: f(x)= 1.5334743087794591
# differential_evolution step 600: f(x)= 1.5334743087794591
# differential_evolution step 601: f(x)= 1.5334743087794591
# differential_evolution step 602: f(x)= 1.5334743087794591
# differential_evolution step 603: f(x)= 1.5333872347397868
# differential_evolution step 604: f(x)= 1.5333872347397868
# differential_evolution step 605: f(x)= 1.5333872347397868
# differential_evolution step 606: f(x)= 1.5333872347397868
# differential_evolution step 607: f(x)= 1.5333872347397868
# differential_evolution step 608: f(x)= 1.5333872347397868
# differential_evolution step 609: f(x)= 1.5333872347397868
# differential_evolution step 610: f(x)= 1.5333872347397868
# differential_evolution step 611: f(x)= 1.5333872347397868
# differential_evolution step 612: f(x)= 1.5333872347397868
# differential_evolution step 613: f(x)= 1.5333872347397868
# differential_evolution step 614: f(x)= 1.5333872347397868
# differential_evolution step 615: f(x)= 1.5333872347397868
# differential_evolution step 616: f(x)= 1.5333872347397868
# differential_evolution step 617: f(x)= 1.5333872347397868
# differential_evolution step 618: f(x)= 1.5333872347397868
# differential_evolution step 619: f(x)= 1.5325018877109968
# differential_evolution step 620: f(x)= 1.5325018877109968
# differential_evolution step 621: f(x)= 1.5325018877109968
# differential_evolution step 622: f(x)= 1.5325018877109968
# differential_evolution step 623: f(x)= 1.5325018877109968
# differential_evolution step 624: f(x)= 1.5325018877109968
# differential_evolution step 625: f(x)= 1.5325018877109968
# differential_evolution step 626: f(x)= 1.5325018877109968
# differential_evolution step 627: f(x)= 1.5325018877109968
# differential_evolution step 628: f(x)= 1.5325018877109968
# differential_evolution step 629: f(x)= 1.5325018877109968
# differential_evolution step 630: f(x)= 1.5325018877109968
# differential_evolution step 631: f(x)= 1.5320538689419063
# differential_evolution step 632: f(x)= 1.5320538689419063
# differential_evolution step 633: f(x)= 1.5315734043364546
# differential_evolution step 634: f(x)= 1.5315734043364546
# differential_evolution step 635: f(x)= 1.5315734043364546
# differential_evolution step 636: f(x)= 1.5315734043364546
# differential_evolution step 637: f(x)= 1.5315734043364546
# differential_evolution step 638: f(x)= 1.5315734043364546
# differential_evolution step 639: f(x)= 1.5315734043364546
# differential_evolution step 640: f(x)= 1.5315734043364546
# differential_evolution step 641: f(x)= 1.5315734043364546
# differential_evolution step 642: f(x)= 1.5315734043364546
# differential_evolution step 643: f(x)= 1.5315734043364546
# differential_evolution step 644: f(x)= 1.5315734043364546
# differential_evolution step 645: f(x)= 1.5315734043364546
# differential_evolution step 646: f(x)= 1.5315734043364546
# differential_evolution step 647: f(x)= 1.5315734043364546
# differential_evolution step 648: f(x)= 1.5315734043364546
# differential_evolution step 649: f(x)= 1.5315734043364546
# differential_evolution step 650: f(x)= 1.5315734043364546
# differential_evolution step 651: f(x)= 1.5315734043364546
# differential_evolution step 652: f(x)= 1.5315734043364546
# differential_evolution step 653: f(x)= 1.5315734043364546
# differential_evolution step 654: f(x)= 1.5315734043364546
# differential_evolution step 655: f(x)= 1.5315734043364546
# differential_evolution step 656: f(x)= 1.5315734043364546
# differential_evolution step 657: f(x)= 1.5315734043364546
# differential_evolution step 658: f(x)= 1.5315734043364546
# differential_evolution step 659: f(x)= 1.531568169900202
# differential_evolution step 660: f(x)= 1.531568169900202
# differential_evolution step 661: f(x)= 1.531568169900202
# differential_evolution step 662: f(x)= 1.531568169900202
# differential_evolution step 663: f(x)= 1.531568169900202
# differential_evolution step 664: f(x)= 1.531568169900202
# differential_evolution step 665: f(x)= 1.531387613522769
# differential_evolution step 666: f(x)= 1.531387613522769
# differential_evolution step 667: f(x)= 1.531387613522769
# differential_evolution step 668: f(x)= 1.531387613522769
# differential_evolution step 669: f(x)= 1.531387613522769
# differential_evolution step 670: f(x)= 1.531387613522769
# differential_evolution step 671: f(x)= 1.531387613522769
# differential_evolution step 672: f(x)= 1.531387613522769
# differential_evolution step 673: f(x)= 1.531387613522769
# differential_evolution step 674: f(x)= 1.531387613522769
# differential_evolution step 675: f(x)= 1.531387613522769
# differential_evolution step 676: f(x)= 1.531387613522769
# differential_evolution step 677: f(x)= 1.531387613522769
# differential_evolution step 678: f(x)= 1.531387613522769
# differential_evolution step 679: f(x)= 1.531387613522769
# differential_evolution step 680: f(x)= 1.531387613522769
# differential_evolution step 681: f(x)= 1.531387613522769
# differential_evolution step 682: f(x)= 1.531387613522769
# differential_evolution step 683: f(x)= 1.531387613522769
# differential_evolution step 684: f(x)= 1.531387613522769
# differential_evolution step 685: f(x)= 1.531387613522769
# differential_evolution step 686: f(x)= 1.531387613522769
# differential_evolution step 687: f(x)= 1.531387613522769
# differential_evolution step 688: f(x)= 1.531387613522769
# differential_evolution step 689: f(x)= 1.531387613522769
# differential_evolution step 690: f(x)= 1.531387613522769
# differential_evolution step 691: f(x)= 1.531387613522769
# differential_evolution step 692: f(x)= 1.531387613522769
# differential_evolution step 693: f(x)= 1.531387613522769
# differential_evolution step 694: f(x)= 1.531387613522769
# differential_evolution step 695: f(x)= 1.531387613522769
# differential_evolution step 696: f(x)= 1.531387613522769
# differential_evolution step 697: f(x)= 1.531387613522769
# differential_evolution step 698: f(x)= 1.531387613522769
# differential_evolution step 699: f(x)= 1.531387613522769
# differential_evolution step 700: f(x)= 1.531387613522769
# differential_evolution step 701: f(x)= 1.531387613522769
# differential_evolution step 702: f(x)= 1.531387613522769
# differential_evolution step 703: f(x)= 1.531387613522769
# differential_evolution step 704: f(x)= 1.531387613522769
# differential_evolution step 705: f(x)= 1.531387613522769
# differential_evolution step 706: f(x)= 1.530946497481991
# differential_evolution step 707: f(x)= 1.530946497481991
# differential_evolution step 708: f(x)= 1.530946497481991
# differential_evolution step 709: f(x)= 1.530946497481991
# differential_evolution step 710: f(x)= 1.530946497481991
# differential_evolution step 711: f(x)= 1.530946497481991
# differential_evolution step 712: f(x)= 1.530946497481991
# differential_evolution step 713: f(x)= 1.530946497481991
# differential_evolution step 714: f(x)= 1.530946497481991
# differential_evolution step 715: f(x)= 1.530946497481991
# differential_evolution step 716: f(x)= 1.530946497481991
# differential_evolution step 717: f(x)= 1.530946497481991
# differential_evolution step 718: f(x)= 1.530946497481991
# differential_evolution step 719: f(x)= 1.530946497481991
# differential_evolution step 720: f(x)= 1.530946497481991
# differential_evolution step 721: f(x)= 1.530946497481991
# differential_evolution step 722: f(x)= 1.530946497481991
# differential_evolution step 723: f(x)= 1.530946497481991
# differential_evolution step 724: f(x)= 1.530946497481991
# differential_evolution step 725: f(x)= 1.530946497481991
# differential_evolution step 726: f(x)= 1.530946497481991
# differential_evolution step 727: f(x)= 1.530946497481991
# differential_evolution step 728: f(x)= 1.530946497481991
# differential_evolution step 729: f(x)= 1.530946497481991
# differential_evolution step 730: f(x)= 1.530946497481991
# differential_evolution step 731: f(x)= 1.530946497481991
# differential_evolution step 732: f(x)= 1.530946497481991
# differential_evolution step 733: f(x)= 1.530946497481991
# differential_evolution step 734: f(x)= 1.5308637291668257
# differential_evolution step 735: f(x)= 1.5308637291668257
# differential_evolution step 736: f(x)= 1.5308637291668257
# differential_evolution step 737: f(x)= 1.5308637291668257
# differential_evolution step 738: f(x)= 1.5308637291668257
# differential_evolution step 739: f(x)= 1.5308637291668257
# differential_evolution step 740: f(x)= 1.5308637291668257
# differential_evolution step 741: f(x)= 1.5308637291668257
# differential_evolution step 742: f(x)= 1.5308637291668257
# differential_evolution step 743: f(x)= 1.5308637291668257
# differential_evolution step 744: f(x)= 1.5308637291668257
# differential_evolution step 745: f(x)= 1.5308637291668257
# differential_evolution step 746: f(x)= 1.5308637291668257
# differential_evolution step 747: f(x)= 1.5308637291668257
# differential_evolution step 748: f(x)= 1.5308637291668257
# differential_evolution step 749: f(x)= 1.5308637291668257
# differential_evolution step 750: f(x)= 1.5308257187958771
# differential_evolution step 751: f(x)= 1.5308257187958771
# differential_evolution step 752: f(x)= 1.5308257187958771
# differential_evolution step 753: f(x)= 1.5308257187958771
# differential_evolution step 754: f(x)= 1.5308257187958771
# differential_evolution step 755: f(x)= 1.5308257187958771
# differential_evolution step 756: f(x)= 1.5308257187958771
# differential_evolution step 757: f(x)= 1.5308257187958771
# differential_evolution step 758: f(x)= 1.5308257187958771
# differential_evolution step 759: f(x)= 1.5308257187958771
# differential_evolution step 760: f(x)= 1.5308257187958771
# differential_evolution step 761: f(x)= 1.5308257187958771
# differential_evolution step 762: f(x)= 1.5308257187958771
# differential_evolution step 763: f(x)= 1.5308257187958771
# differential_evolution step 764: f(x)= 1.5308257187958771
# differential_evolution step 765: f(x)= 1.5308257187958771
# differential_evolution step 766: f(x)= 1.5308257187958771
# differential_evolution step 767: f(x)= 1.5308257187958771
# differential_evolution step 768: f(x)= 1.5308257187958771
# differential_evolution step 769: f(x)= 1.5308257187958771
# differential_evolution step 770: f(x)= 1.5308257187958771
# differential_evolution step 771: f(x)= 1.5308257187958771
# differential_evolution step 772: f(x)= 1.5308257187958771
# differential_evolution step 773: f(x)= 1.5308257187958771
# differential_evolution step 774: f(x)= 1.5308257187958771
# differential_evolution step 775: f(x)= 1.5308257187958771
# differential_evolution step 776: f(x)= 1.5308257187958771
# differential_evolution step 777: f(x)= 1.5308257187958771
# differential_evolution step 778: f(x)= 1.5308257187958771
# differential_evolution step 779: f(x)= 1.5308257187958771
# differential_evolution step 780: f(x)= 1.5308257187958771
# differential_evolution step 781: f(x)= 1.5308257187958771
# differential_evolution step 782: f(x)= 1.5308257187958771
# differential_evolution step 783: f(x)= 1.5308257187958771
# differential_evolution step 784: f(x)= 1.5308257187958771
# differential_evolution step 785: f(x)= 1.5308257187958771
# differential_evolution step 786: f(x)= 1.5308257187958771
# differential_evolution step 787: f(x)= 1.5308257187958771
# differential_evolution step 788: f(x)= 1.5308257187958771
# differential_evolution step 789: f(x)= 1.5308257187958771
# differential_evolution step 790: f(x)= 1.5308257187958771
# differential_evolution step 791: f(x)= 1.5308257187958771
# differential_evolution step 792: f(x)= 1.5308257187958771
# differential_evolution step 793: f(x)= 1.5308220272045392
# differential_evolution step 794: f(x)= 1.5308220272045392
# differential_evolution step 795: f(x)= 1.5308220272045392
# differential_evolution step 796: f(x)= 1.5308220272045392
# differential_evolution step 797: f(x)= 1.5308220272045392
# differential_evolution step 798: f(x)= 1.5308220272045392
# differential_evolution step 799: f(x)= 1.5308220272045392
# differential_evolution step 800: f(x)= 1.5308220272045392
# differential_evolution step 801: f(x)= 1.5308220272045392
# differential_evolution step 802: f(x)= 1.5306982742062478
# differential_evolution step 803: f(x)= 1.5306982742062478
# differential_evolution step 804: f(x)= 1.5306982742062478
# differential_evolution step 805: f(x)= 1.5306982742062478
# differential_evolution step 806: f(x)= 1.5306982742062478
# differential_evolution step 807: f(x)= 1.5306982742062478
# differential_evolution step 808: f(x)= 1.5306982742062478
# differential_evolution step 809: f(x)= 1.5306982742062478
# differential_evolution step 810: f(x)= 1.5306982742062478
# differential_evolution step 811: f(x)= 1.5306982742062478
# differential_evolution step 812: f(x)= 1.5306982742062478
# differential_evolution step 813: f(x)= 1.5306982742062478
# differential_evolution step 814: f(x)= 1.5306982742062478
# differential_evolution step 815: f(x)= 1.5306982742062478
# differential_evolution step 816: f(x)= 1.5306982742062478
# differential_evolution step 817: f(x)= 1.530687474963859
# differential_evolution step 818: f(x)= 1.530687474963859
# differential_evolution step 819: f(x)= 1.530687474963859
# differential_evolution step 820: f(x)= 1.530687474963859
# differential_evolution step 821: f(x)= 1.530687474963859
# differential_evolution step 822: f(x)= 1.530687474963859
# differential_evolution step 823: f(x)= 1.530687474963859
# differential_evolution step 824: f(x)= 1.530687474963859
# differential_evolution step 825: f(x)= 1.530687474963859
# differential_evolution step 826: f(x)= 1.5306729145165248
# differential_evolution step 827: f(x)= 1.5306729145165248
# differential_evolution step 828: f(x)= 1.5306644735013093
# differential_evolution step 829: f(x)= 1.5306644735013093
# differential_evolution step 830: f(x)= 1.5306644735013093
# differential_evolution step 831: f(x)= 1.5306644735013093
# differential_evolution step 832: f(x)= 1.5306644735013093
# differential_evolution step 833: f(x)= 1.5305875499442954
# differential_evolution step 834: f(x)= 1.5305875499442954
# differential_evolution step 835: f(x)= 1.5305875499442954
# differential_evolution step 836: f(x)= 1.5305875499442954
# differential_evolution step 837: f(x)= 1.5305875499442954
# differential_evolution step 838: f(x)= 1.5305875499442954
# differential_evolution step 839: f(x)= 1.5305875499442954
# differential_evolution step 840: f(x)= 1.5305875499442954
# differential_evolution step 841: f(x)= 1.5305875499442954
# differential_evolution step 842: f(x)= 1.5305875499442954
# differential_evolution step 843: f(x)= 1.5305875499442954
# differential_evolution step 844: f(x)= 1.5305875499442954
# differential_evolution step 845: f(x)= 1.5305875499442954
# differential_evolution step 846: f(x)= 1.5305875499442954
# differential_evolution step 847: f(x)= 1.5305875499442954
# differential_evolution step 848: f(x)= 1.5305875499442954
# differential_evolution step 849: f(x)= 1.5305875499442954
# differential_evolution step 850: f(x)= 1.5305875499442954
# differential_evolution step 851: f(x)= 1.5305875499442954
# differential_evolution step 852: f(x)= 1.5305875499442954
# differential_evolution step 853: f(x)= 1.5305875499442954
# differential_evolution step 854: f(x)= 1.5305875499442954
# differential_evolution step 855: f(x)= 1.5305875499442954
# differential_evolution step 856: f(x)= 1.5305875499442954
# differential_evolution step 857: f(x)= 1.5305875499442954
# differential_evolution step 858: f(x)= 1.5305875499442954
# differential_evolution step 859: f(x)= 1.5305875499442954
# differential_evolution step 860: f(x)= 1.5305875499442954
# differential_evolution step 861: f(x)= 1.5305875499442954
# differential_evolution step 862: f(x)= 1.5305875499442954
# differential_evolution step 863: f(x)= 1.5305875499442954
# differential_evolution step 864: f(x)= 1.5305875499442954
# differential_evolution step 865: f(x)= 1.5305875499442954
# differential_evolution step 866: f(x)= 1.5305875499442954
# differential_evolution step 867: f(x)= 1.5305875499442954
# differential_evolution step 868: f(x)= 1.5305875499442954
# differential_evolution step 869: f(x)= 1.5305875499442954
# differential_evolution step 870: f(x)= 1.5305875499442954
# differential_evolution step 871: f(x)= 1.5305875499442954
# differential_evolution step 872: f(x)= 1.5305875499442954
# differential_evolution step 873: f(x)= 1.5305875499442954
# differential_evolution step 874: f(x)= 1.5305693790240757
# differential_evolution step 875: f(x)= 1.5305693790240757
# differential_evolution step 876: f(x)= 1.5305693790240757
# differential_evolution step 877: f(x)= 1.5305693790240757
# differential_evolution step 878: f(x)= 1.5305557477621714
# differential_evolution step 879: f(x)= 1.5305557477621714
# differential_evolution step 880: f(x)= 1.530547295081628
# differential_evolution step 881: f(x)= 1.530547295081628
# differential_evolution step 882: f(x)= 1.530547295081628
# differential_evolution step 883: f(x)= 1.530547295081628
# differential_evolution step 884: f(x)= 1.530547295081628
# differential_evolution step 885: f(x)= 1.530547295081628
# differential_evolution step 886: f(x)= 1.530547295081628
# differential_evolution step 887: f(x)= 1.530547295081628
# differential_evolution step 888: f(x)= 1.530547295081628
# differential_evolution step 889: f(x)= 1.530547295081628
# differential_evolution step 890: f(x)= 1.530547295081628
# differential_evolution step 891: f(x)= 1.530547295081628
# differential_evolution step 892: f(x)= 1.530547295081628
# differential_evolution step 893: f(x)= 1.530547295081628
# differential_evolution step 894: f(x)= 1.530547295081628
# differential_evolution step 895: f(x)= 1.530547295081628
# differential_evolution step 896: f(x)= 1.5305363212952652
# differential_evolution step 897: f(x)= 1.5305363212952652
# differential_evolution step 898: f(x)= 1.5305133376268651
# differential_evolution step 899: f(x)= 1.5305133376268651
# differential_evolution step 900: f(x)= 1.5305133376268651
# differential_evolution step 901: f(x)= 1.5305133376268651
# differential_evolution step 902: f(x)= 1.5305133376268651
# differential_evolution step 903: f(x)= 1.5305133376268651
# differential_evolution step 904: f(x)= 1.5305133376268651
# differential_evolution step 905: f(x)= 1.5305133376268651
# differential_evolution step 906: f(x)= 1.5305133376268651
# differential_evolution step 907: f(x)= 1.530510281370368
# differential_evolution step 908: f(x)= 1.530510281370368
# differential_evolution step 909: f(x)= 1.530510281370368
# differential_evolution step 910: f(x)= 1.530510281370368
# differential_evolution step 911: f(x)= 1.530503175208236
# differential_evolution step 912: f(x)= 1.530503175208236
# differential_evolution step 913: f(x)= 1.530503175208236
# differential_evolution step 914: f(x)= 1.530503175208236
# differential_evolution step 915: f(x)= 1.530503175208236
# differential_evolution step 916: f(x)= 1.530503175208236
# differential_evolution step 917: f(x)= 1.5305018514161148
# differential_evolution step 918: f(x)= 1.5305018514161148
# differential_evolution step 919: f(x)= 1.5305018514161148
# differential_evolution step 920: f(x)= 1.5305018514161148
# differential_evolution step 921: f(x)= 1.5305018514161148
# differential_evolution step 922: f(x)= 1.5305018514161148
# differential_evolution step 923: f(x)= 1.5304941334701319
# differential_evolution step 924: f(x)= 1.530480243695046
# differential_evolution step 925: f(x)= 1.530480243695046
# differential_evolution step 926: f(x)= 1.530480243695046
# differential_evolution step 927: f(x)= 1.530480243695046
# differential_evolution step 928: f(x)= 1.530480243695046
# differential_evolution step 929: f(x)= 1.530480243695046
# differential_evolution step 930: f(x)= 1.530480243695046
# differential_evolution step 931: f(x)= 1.530480243695046
# differential_evolution step 932: f(x)= 1.530480243695046
# differential_evolution step 933: f(x)= 1.530480243695046
# differential_evolution step 934: f(x)= 1.530480243695046
# differential_evolution step 935: f(x)= 1.530480243695046
# differential_evolution step 936: f(x)= 1.530480243695046
# differential_evolution step 937: f(x)= 1.530480243695046
# differential_evolution step 938: f(x)= 1.530480243695046
# differential_evolution step 939: f(x)= 1.530480243695046
# differential_evolution step 940: f(x)= 1.530480243695046
# differential_evolution step 941: f(x)= 1.530480243695046
# differential_evolution step 942: f(x)= 1.530480243695046
# differential_evolution step 943: f(x)= 1.530480243695046
# differential_evolution step 944: f(x)= 1.530480243695046
# differential_evolution step 945: f(x)= 1.530480243695046
# differential_evolution step 946: f(x)= 1.530480243695046
# differential_evolution step 947: f(x)= 1.530480243695046
# differential_evolution step 948: f(x)= 1.530480243695046
# differential_evolution step 949: f(x)= 1.5304656389788678
# differential_evolution step 950: f(x)= 1.5304607239800454
# differential_evolution step 951: f(x)= 1.5304607239800454
# differential_evolution step 952: f(x)= 1.5304607239800454
# differential_evolution step 953: f(x)= 1.5304607239800454
# differential_evolution step 954: f(x)= 1.5304607239800454
# differential_evolution step 955: f(x)= 1.5304607239800454
# differential_evolution step 956: f(x)= 1.5304601698133464
# differential_evolution step 957: f(x)= 1.5304588670868422
# differential_evolution step 958: f(x)= 1.5304588670868422
# differential_evolution step 959: f(x)= 1.5304588670868422
# differential_evolution step 960: f(x)= 1.5304588670868422
# differential_evolution step 961: f(x)= 1.5304588670868422
# differential_evolution step 962: f(x)= 1.5304588670868422
# differential_evolution step 963: f(x)= 1.5304588670868422
# differential_evolution step 964: f(x)= 1.5304588670868422
# differential_evolution step 965: f(x)= 1.5304588670868422
# differential_evolution step 966: f(x)= 1.5304588670868422
# differential_evolution step 967: f(x)= 1.5304588670868422
# differential_evolution step 968: f(x)= 1.5304588670868422
# differential_evolution step 969: f(x)= 1.5304588670868422
# differential_evolution step 970: f(x)= 1.5304588670868422
# differential_evolution step 971: f(x)= 1.5304588670868422
# differential_evolution step 972: f(x)= 1.5304588670868422
# differential_evolution step 973: f(x)= 1.5304588670868422
# differential_evolution step 974: f(x)= 1.5304588670868422
# differential_evolution step 975: f(x)= 1.5304588670868422
# differential_evolution step 976: f(x)= 1.5304588670868422
# differential_evolution step 977: f(x)= 1.5304588670868422
# differential_evolution step 978: f(x)= 1.5304588670868422
# differential_evolution step 979: f(x)= 1.5304588670868422
# differential_evolution step 980: f(x)= 1.5304588670868422
# differential_evolution step 981: f(x)= 1.5304588670868422
# differential_evolution step 982: f(x)= 1.5304588670868422
# differential_evolution step 983: f(x)= 1.5304588670868422
# differential_evolution step 984: f(x)= 1.5304588670868422
# differential_evolution step 985: f(x)= 1.5304588670868422
# differential_evolution step 986: f(x)= 1.5304588670868422
# differential_evolution step 987: f(x)= 1.5304588670868422
# differential_evolution step 988: f(x)= 1.5304588670868422
# differential_evolution step 989: f(x)= 1.5304588670868422
# differential_evolution step 990: f(x)= 1.5304588670868422
# differential_evolution step 991: f(x)= 1.5304588670868422
# differential_evolution step 992: f(x)= 1.5304588670868422
# differential_evolution step 993: f(x)= 1.5304588670868422
# differential_evolution step 994: f(x)= 1.5304588670868422
# differential_evolution step 995: f(x)= 1.5304507453891765
# differential_evolution step 996: f(x)= 1.5304507453891765
# differential_evolution step 997: f(x)= 1.5304507453891765
# differential_evolution step 998: f(x)= 1.5304507453891765
# differential_evolution step 999: f(x)= 1.5304507453891765
# differential_evolution step 1000: f(x)= 1.5304421500894365
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.3203, r_e=26.7449, n=1.6331, x_0=44.1535
# Sérsic 2: I_e=2.3684, r_e=6.7252, n=0.3001, x_0=52.6045
# Sérsic 3: I_e=1.2865, r_e=6.4113, n=0.7559, x_0=61.9384
# Chi quadro minimo: 1.5304310450415899
# False

# %%
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = radial_profile_error_SII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, radial_profile_error_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1153, r_e=50.0000, n=2.2722, x_0=44.4933
# Sérsic 2: I_e=1.3516, r_e=8.5012, n=0.6478, x_0=50.6527
# Sérsic 3: I_e=1.5949, r_e=6.3088, n=0.7333, x_0=60.8398
# [ 0.03751725 10.12627979  0.2046779   0.11018446  0.13507777  0.6663006
#   0.06101019  0.40905538  0.12229017  0.19830951  0.03761183  0.16706998]
# 10.794698152083878

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_8612\736486982.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 6))
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 7914.735843077336
# differential_evolution step 2: f(x)= 3443.1560051665674
# differential_evolution step 3: f(x)= 1354.557825642908
# differential_evolution step 4: f(x)= 1354.557825642908
# differential_evolution step 5: f(x)= 1354.557825642908
# differential_evolution step 6: f(x)= 794.1410725080401
# differential_evolution step 7: f(x)= 794.1410725080401
# differential_evolution step 8: f(x)= 759.3148691489351
# differential_evolution step 9: f(x)= 691.3718186821411
# differential_evolution step 10: f(x)= 691.3718186821411
# differential_evolution step 11: f(x)= 691.3718186821411
# differential_evolution step 12: f(x)= 691.3718186821411
# differential_evolution step 13: f(x)= 691.3718186821411
# differential_evolution step 14: f(x)= 555.736914143113
# differential_evolution step 15: f(x)= 555.736914143113
# differential_evolution step 16: f(x)= 555.736914143113
# differential_evolution step 17: f(x)= 555.736914143113
# differential_evolution step 18: f(x)= 499.9508489626763
# differential_evolution step 19: f(x)= 499.9508489626763
# differential_evolution step 20: f(x)= 499.9508489626763
# differential_evolution step 21: f(x)= 349.10179352793176
# differential_evolution step 22: f(x)= 349.10179352793176
# differential_evolution step 23: f(x)= 349.10179352793176
# differential_evolution step 24: f(x)= 349.10179352793176
# differential_evolution step 25: f(x)= 349.10179352793176
# differential_evolution step 26: f(x)= 349.10179352793176
# differential_evolution step 27: f(x)= 349.10179352793176
# differential_evolution step 28: f(x)= 349.10179352793176
# differential_evolution step 29: f(x)= 349.10179352793176
# differential_evolution step 30: f(x)= 323.9441873188136
# differential_evolution step 31: f(x)= 323.9441873188136
# differential_evolution step 32: f(x)= 323.9441873188136
# differential_evolution step 33: f(x)= 323.9441873188136
# differential_evolution step 34: f(x)= 323.9441873188136
# differential_evolution step 35: f(x)= 302.77731500689487
# differential_evolution step 36: f(x)= 264.99098558156027
# differential_evolution step 37: f(x)= 264.99098558156027
# differential_evolution step 38: f(x)= 264.99098558156027
# differential_evolution step 39: f(x)= 264.99098558156027
# differential_evolution step 40: f(x)= 261.8835991440329
# differential_evolution step 41: f(x)= 261.8835991440329
# differential_evolution step 42: f(x)= 261.8835991440329
# differential_evolution step 43: f(x)= 261.8835991440329
# differential_evolution step 44: f(x)= 208.73268700975197
# differential_evolution step 45: f(x)= 208.73268700975197
# differential_evolution step 46: f(x)= 208.73268700975197
# differential_evolution step 47: f(x)= 208.73268700975197
# differential_evolution step 48: f(x)= 208.73268700975197
# differential_evolution step 49: f(x)= 208.73268700975197
# differential_evolution step 50: f(x)= 208.73268700975197
# differential_evolution step 51: f(x)= 208.73268700975197
# differential_evolution step 52: f(x)= 208.73268700975197
# differential_evolution step 53: f(x)= 197.93472241537765
# differential_evolution step 54: f(x)= 190.1504505208606
# differential_evolution step 55: f(x)= 190.1504505208606
# differential_evolution step 56: f(x)= 173.44809432084287
# differential_evolution step 57: f(x)= 173.44809432084287
# differential_evolution step 58: f(x)= 173.44809432084287
# differential_evolution step 59: f(x)= 173.44809432084287
# differential_evolution step 60: f(x)= 173.44809432084287
# differential_evolution step 61: f(x)= 156.21041654207804
# differential_evolution step 62: f(x)= 156.21041654207804
# differential_evolution step 63: f(x)= 156.21041654207804
# differential_evolution step 64: f(x)= 156.21041654207804
# differential_evolution step 65: f(x)= 156.21041654207804
# differential_evolution step 66: f(x)= 156.21041654207804
# differential_evolution step 67: f(x)= 152.74423996759606
# differential_evolution step 68: f(x)= 152.74423996759606
# differential_evolution step 69: f(x)= 152.74423996759606
# differential_evolution step 70: f(x)= 152.74423996759606
# differential_evolution step 71: f(x)= 152.74423996759606
# differential_evolution step 72: f(x)= 152.74423996759606
# differential_evolution step 73: f(x)= 152.74423996759606
# differential_evolution step 74: f(x)= 152.74423996759606
# differential_evolution step 75: f(x)= 152.74423996759606
# differential_evolution step 76: f(x)= 152.74423996759606
# differential_evolution step 77: f(x)= 150.4593882655263
# differential_evolution step 78: f(x)= 150.4593882655263
# differential_evolution step 79: f(x)= 149.0485173729678
# differential_evolution step 80: f(x)= 134.49549604866547
# differential_evolution step 81: f(x)= 134.49549604866547
# differential_evolution step 82: f(x)= 134.49549604866547
# differential_evolution step 83: f(x)= 134.49549604866547
# differential_evolution step 84: f(x)= 134.49549604866547
# differential_evolution step 85: f(x)= 134.49549604866547
# differential_evolution step 86: f(x)= 130.07737317881455
# differential_evolution step 87: f(x)= 121.47801599020586
# differential_evolution step 88: f(x)= 121.47801599020586
# differential_evolution step 89: f(x)= 121.47801599020586
# differential_evolution step 90: f(x)= 121.47801599020586
# differential_evolution step 91: f(x)= 121.47801599020586
# differential_evolution step 92: f(x)= 121.47801599020586
# differential_evolution step 93: f(x)= 121.47801599020586
# differential_evolution step 94: f(x)= 121.47801599020586
# differential_evolution step 95: f(x)= 121.47801599020586
# differential_evolution step 96: f(x)= 121.47801599020586
# differential_evolution step 97: f(x)= 109.18013865235164
# differential_evolution step 98: f(x)= 109.18013865235164
# differential_evolution step 99: f(x)= 109.18013865235164
# differential_evolution step 100: f(x)= 109.18013865235164
# differential_evolution step 101: f(x)= 109.18013865235164
# differential_evolution step 102: f(x)= 109.18013865235164
# differential_evolution step 103: f(x)= 109.18013865235164
# differential_evolution step 104: f(x)= 109.18013865235164
# differential_evolution step 105: f(x)= 109.18013865235164
# differential_evolution step 106: f(x)= 109.18013865235164
# differential_evolution step 107: f(x)= 109.18013865235164
# differential_evolution step 108: f(x)= 104.65416777652628
# differential_evolution step 109: f(x)= 104.65416777652628
# differential_evolution step 110: f(x)= 104.65416777652628
# differential_evolution step 111: f(x)= 94.46610724106552
# differential_evolution step 112: f(x)= 94.46610724106552
# differential_evolution step 113: f(x)= 94.46610724106552
# differential_evolution step 114: f(x)= 94.46610724106552
# differential_evolution step 115: f(x)= 94.46610724106552
# differential_evolution step 116: f(x)= 94.46610724106552
# differential_evolution step 117: f(x)= 94.46610724106552
# differential_evolution step 118: f(x)= 94.46610724106552
# differential_evolution step 119: f(x)= 94.46610724106552
# differential_evolution step 120: f(x)= 94.46610724106552
# differential_evolution step 121: f(x)= 94.46610724106552
# differential_evolution step 122: f(x)= 94.46610724106552
# differential_evolution step 123: f(x)= 94.46610724106552
# differential_evolution step 124: f(x)= 94.46610724106552
# differential_evolution step 125: f(x)= 94.46610724106552
# differential_evolution step 126: f(x)= 94.46610724106552
# differential_evolution step 127: f(x)= 94.46610724106552
# differential_evolution step 128: f(x)= 91.38526194189451
# differential_evolution step 129: f(x)= 91.38526194189451
# differential_evolution step 130: f(x)= 91.38526194189451
# differential_evolution step 131: f(x)= 91.38526194189451
# differential_evolution step 132: f(x)= 91.38526194189451
# differential_evolution step 133: f(x)= 91.38526194189451
# differential_evolution step 134: f(x)= 91.38526194189451
# differential_evolution step 135: f(x)= 91.38526194189451
# differential_evolution step 136: f(x)= 91.38526194189451
# differential_evolution step 137: f(x)= 91.38526194189451
# differential_evolution step 138: f(x)= 91.38526194189451
# differential_evolution step 139: f(x)= 91.38526194189451
# differential_evolution step 140: f(x)= 91.38526194189451
# differential_evolution step 141: f(x)= 91.38526194189451
# differential_evolution step 142: f(x)= 91.38526194189451
# differential_evolution step 143: f(x)= 91.38526194189451
# differential_evolution step 144: f(x)= 91.38526194189451
# differential_evolution step 145: f(x)= 91.38526194189451
# differential_evolution step 146: f(x)= 90.94517226719557
# differential_evolution step 147: f(x)= 90.07310311971513
# differential_evolution step 148: f(x)= 90.07310311971513
# differential_evolution step 149: f(x)= 90.07310311971513
# differential_evolution step 150: f(x)= 90.07310311971513
# differential_evolution step 151: f(x)= 90.07310311971513
# differential_evolution step 152: f(x)= 90.07310311971513
# differential_evolution step 153: f(x)= 90.07310311971513
# differential_evolution step 154: f(x)= 90.07310311971513
# differential_evolution step 155: f(x)= 90.07310311971513
# differential_evolution step 156: f(x)= 90.07310311971513
# differential_evolution step 157: f(x)= 87.7768332891479
# differential_evolution step 158: f(x)= 87.7768332891479
# differential_evolution step 159: f(x)= 87.7768332891479
# differential_evolution step 160: f(x)= 87.74144625230515
# differential_evolution step 161: f(x)= 87.74144625230515
# differential_evolution step 162: f(x)= 87.74144625230515
# differential_evolution step 163: f(x)= 87.74144625230515
# differential_evolution step 164: f(x)= 87.74144625230515
# differential_evolution step 165: f(x)= 87.74144625230515
# differential_evolution step 166: f(x)= 86.8356075420494
# differential_evolution step 167: f(x)= 86.8356075420494
# differential_evolution step 168: f(x)= 86.65582991684435
# differential_evolution step 169: f(x)= 86.312514343954
# differential_evolution step 170: f(x)= 86.312514343954
# differential_evolution step 171: f(x)= 86.312514343954
# differential_evolution step 172: f(x)= 86.312514343954
# differential_evolution step 173: f(x)= 86.312514343954
# differential_evolution step 174: f(x)= 86.312514343954
# differential_evolution step 175: f(x)= 86.312514343954
# differential_evolution step 176: f(x)= 86.312514343954
# differential_evolution step 177: f(x)= 85.89624952528425
# differential_evolution step 178: f(x)= 85.89624952528425
# differential_evolution step 179: f(x)= 85.89624952528425
# differential_evolution step 180: f(x)= 85.42041484526136
# differential_evolution step 181: f(x)= 85.04208332689183
# differential_evolution step 182: f(x)= 85.04208332689183
# differential_evolution step 183: f(x)= 85.04208332689183
# differential_evolution step 184: f(x)= 85.04208332689183
# differential_evolution step 185: f(x)= 84.64568034257042
# differential_evolution step 186: f(x)= 84.64568034257042
# differential_evolution step 187: f(x)= 84.64568034257042
# differential_evolution step 188: f(x)= 84.64568034257042
# differential_evolution step 189: f(x)= 84.64568034257042
# differential_evolution step 190: f(x)= 84.37627952170682
# differential_evolution step 191: f(x)= 84.37627952170682
# differential_evolution step 192: f(x)= 84.37627952170682
# differential_evolution step 193: f(x)= 84.37627952170682
# differential_evolution step 194: f(x)= 84.37627952170682
# differential_evolution step 195: f(x)= 84.37627952170682
# differential_evolution step 196: f(x)= 84.37627952170682
# differential_evolution step 197: f(x)= 84.37627952170682
# differential_evolution step 198: f(x)= 84.37627952170682
# differential_evolution step 199: f(x)= 84.37627952170682
# differential_evolution step 200: f(x)= 84.37627952170682
# differential_evolution step 201: f(x)= 84.3230468670322
# differential_evolution step 202: f(x)= 83.84484831369925
# differential_evolution step 203: f(x)= 83.84484831369925
# differential_evolution step 204: f(x)= 83.54716846155816
# differential_evolution step 205: f(x)= 83.54716846155816
# differential_evolution step 206: f(x)= 83.54716846155816
# differential_evolution step 207: f(x)= 83.54716846155816
# differential_evolution step 208: f(x)= 83.54716846155816
# differential_evolution step 209: f(x)= 83.54716846155816
# differential_evolution step 210: f(x)= 83.54716846155816
# differential_evolution step 211: f(x)= 83.54716846155816
# differential_evolution step 212: f(x)= 83.54716846155816
# differential_evolution step 213: f(x)= 83.54716846155816
# differential_evolution step 214: f(x)= 83.54716846155816
# differential_evolution step 215: f(x)= 83.54716846155816
# differential_evolution step 216: f(x)= 83.54716846155816
# differential_evolution step 217: f(x)= 83.54716846155816
# differential_evolution step 218: f(x)= 83.49132207438822
# differential_evolution step 219: f(x)= 83.49132207438822
# differential_evolution step 220: f(x)= 83.44851897594101
# differential_evolution step 221: f(x)= 83.23714748138248
# differential_evolution step 222: f(x)= 83.23714748138248
# differential_evolution step 223: f(x)= 83.23714748138248
# differential_evolution step 224: f(x)= 83.08019184710899
# differential_evolution step 225: f(x)= 83.08019184710899
# differential_evolution step 226: f(x)= 83.08019184710899
# differential_evolution step 227: f(x)= 83.08019184710899
# differential_evolution step 228: f(x)= 83.08019184710899
# differential_evolution step 229: f(x)= 83.08019184710899
# differential_evolution step 230: f(x)= 83.08019184710899
# differential_evolution step 231: f(x)= 83.08019184710899
# differential_evolution step 232: f(x)= 83.08019184710899
# differential_evolution step 233: f(x)= 83.08019184710899
# differential_evolution step 234: f(x)= 83.08019184710899
# differential_evolution step 235: f(x)= 83.08019184710899
# differential_evolution step 236: f(x)= 83.08019184710899
# differential_evolution step 237: f(x)= 83.08019184710899
# differential_evolution step 238: f(x)= 83.08019184710899
# differential_evolution step 239: f(x)= 83.08019184710899
# differential_evolution step 240: f(x)= 83.08019184710899
# differential_evolution step 241: f(x)= 83.08019184710899
# differential_evolution step 242: f(x)= 83.08019184710899
# differential_evolution step 243: f(x)= 83.07925315194143
# differential_evolution step 244: f(x)= 83.07925315194143
# differential_evolution step 245: f(x)= 83.07925315194143
# differential_evolution step 246: f(x)= 83.07925315194143
# differential_evolution step 247: f(x)= 83.07925315194143
# differential_evolution step 248: f(x)= 83.07925315194143
# differential_evolution step 249: f(x)= 83.07925315194143
# differential_evolution step 250: f(x)= 83.07925315194143
# differential_evolution step 251: f(x)= 83.07925315194143
# differential_evolution step 252: f(x)= 83.07925315194143
# differential_evolution step 253: f(x)= 83.07925315194143
# differential_evolution step 254: f(x)= 82.86400887854609
# differential_evolution step 255: f(x)= 82.86400887854609
# differential_evolution step 256: f(x)= 82.86400887854609
# differential_evolution step 257: f(x)= 82.86400887854609
# differential_evolution step 258: f(x)= 82.86400887854609
# differential_evolution step 259: f(x)= 82.86400887854609
# differential_evolution step 260: f(x)= 82.86400887854609
# differential_evolution step 261: f(x)= 82.86400887854609
# differential_evolution step 262: f(x)= 82.80250170935372
# differential_evolution step 263: f(x)= 82.80250170935372
# differential_evolution step 264: f(x)= 82.76211019981773
# differential_evolution step 265: f(x)= 82.76211019981773
# differential_evolution step 266: f(x)= 82.69861216910851
# differential_evolution step 267: f(x)= 82.69861216910851
# differential_evolution step 268: f(x)= 82.69861216910851
# differential_evolution step 269: f(x)= 82.69861216910851
# differential_evolution step 270: f(x)= 82.64061499077968
# differential_evolution step 271: f(x)= 82.64061499077968
# differential_evolution step 272: f(x)= 82.63078090449882
# differential_evolution step 273: f(x)= 82.63078090449882
# differential_evolution step 274: f(x)= 82.63078090449882
# differential_evolution step 275: f(x)= 82.63078090449882
# differential_evolution step 276: f(x)= 82.63078090449882
# differential_evolution step 277: f(x)= 82.63078090449882
# differential_evolution step 278: f(x)= 82.63078090449882
# differential_evolution step 279: f(x)= 82.55967411150255
# differential_evolution step 280: f(x)= 82.55967411150255
# differential_evolution step 281: f(x)= 82.55967411150255
# differential_evolution step 282: f(x)= 82.55967411150255
# differential_evolution step 283: f(x)= 82.55967411150255
# differential_evolution step 284: f(x)= 82.55967411150255
# differential_evolution step 285: f(x)= 82.55967411150255
# differential_evolution step 286: f(x)= 82.55967411150255
# differential_evolution step 287: f(x)= 82.55967411150255
# differential_evolution step 288: f(x)= 82.55967411150255
# differential_evolution step 289: f(x)= 82.55967411150255
# differential_evolution step 290: f(x)= 82.54543165029389
# differential_evolution step 291: f(x)= 82.54543165029389
# differential_evolution step 292: f(x)= 82.54543165029389
# differential_evolution step 293: f(x)= 82.54543165029389
# differential_evolution step 294: f(x)= 82.54543165029389
# differential_evolution step 295: f(x)= 82.51843736941089
# differential_evolution step 296: f(x)= 82.51843736941089
# differential_evolution step 297: f(x)= 82.51843736941089
# differential_evolution step 298: f(x)= 82.51843736941089
# differential_evolution step 299: f(x)= 82.51843736941089
# differential_evolution step 300: f(x)= 82.51843736941089
# differential_evolution step 301: f(x)= 82.51843736941089
# differential_evolution step 302: f(x)= 82.512466530456
# differential_evolution step 303: f(x)= 82.512466530456
# differential_evolution step 304: f(x)= 82.512466530456
# differential_evolution step 305: f(x)= 82.512466530456
# differential_evolution step 306: f(x)= 82.512466530456
# differential_evolution step 307: f(x)= 82.512466530456
# differential_evolution step 308: f(x)= 82.45207168373052
# differential_evolution step 309: f(x)= 82.45207168373052
# differential_evolution step 310: f(x)= 82.45207168373052
# differential_evolution step 311: f(x)= 82.45207168373052
# differential_evolution step 312: f(x)= 82.45207168373052
# differential_evolution step 313: f(x)= 82.45207168373052
# differential_evolution step 314: f(x)= 82.45207168373052
# differential_evolution step 315: f(x)= 82.45207168373052
# differential_evolution step 316: f(x)= 82.45207168373052
# differential_evolution step 317: f(x)= 82.45207168373052
# differential_evolution step 318: f(x)= 82.45207168373052
# differential_evolution step 319: f(x)= 82.45207168373052
# differential_evolution step 320: f(x)= 82.45207168373052
# differential_evolution step 321: f(x)= 82.45207168373052
# differential_evolution step 322: f(x)= 82.45207168373052
# differential_evolution step 323: f(x)= 82.45207168373052
# differential_evolution step 324: f(x)= 82.45207168373052
# differential_evolution step 325: f(x)= 82.45207168373052
# differential_evolution step 326: f(x)= 82.45207168373052
# differential_evolution step 327: f(x)= 82.45207168373052
# differential_evolution step 328: f(x)= 82.45207168373052
# differential_evolution step 329: f(x)= 82.45207168373052
# differential_evolution step 330: f(x)= 82.45207168373052
# differential_evolution step 331: f(x)= 82.45207168373052
# differential_evolution step 332: f(x)= 82.45207168373052
# differential_evolution step 333: f(x)= 82.45207168373052
# differential_evolution step 334: f(x)= 82.45207168373052
# differential_evolution step 335: f(x)= 82.43956792061138
# differential_evolution step 336: f(x)= 82.43956792061138
# differential_evolution step 337: f(x)= 82.43956792061138
# differential_evolution step 338: f(x)= 82.43956792061138
# differential_evolution step 339: f(x)= 82.43956792061138
# differential_evolution step 340: f(x)= 82.435119155364
# differential_evolution step 341: f(x)= 82.435119155364
# differential_evolution step 342: f(x)= 82.435119155364
# differential_evolution step 343: f(x)= 82.435119155364
# differential_evolution step 344: f(x)= 82.435119155364
# differential_evolution step 345: f(x)= 82.4166182289484
# differential_evolution step 346: f(x)= 82.4166182289484
# differential_evolution step 347: f(x)= 82.38683804606458
# differential_evolution step 348: f(x)= 82.38683804606458
# differential_evolution step 349: f(x)= 82.38683804606458
# differential_evolution step 350: f(x)= 82.38683804606458
# differential_evolution step 351: f(x)= 82.38683804606458
# differential_evolution step 352: f(x)= 82.38683804606458
# differential_evolution step 353: f(x)= 82.38683804606458
# differential_evolution step 354: f(x)= 82.35271646644951
# differential_evolution step 355: f(x)= 82.35271646644951
# differential_evolution step 356: f(x)= 82.35271646644951
# differential_evolution step 357: f(x)= 82.35271646644951
# differential_evolution step 358: f(x)= 82.35271646644951
# differential_evolution step 359: f(x)= 82.35271646644951
# differential_evolution step 360: f(x)= 82.35271646644951
# differential_evolution step 361: f(x)= 82.35271646644951
# differential_evolution step 362: f(x)= 82.35271646644951
# differential_evolution step 363: f(x)= 82.35271646644951
# differential_evolution step 364: f(x)= 82.35271646644951
# differential_evolution step 365: f(x)= 82.35271646644951
# differential_evolution step 366: f(x)= 82.35271646644951
# differential_evolution step 367: f(x)= 82.35271646644951
# differential_evolution step 368: f(x)= 82.35271646644951
# differential_evolution step 369: f(x)= 82.35271646644951
# differential_evolution step 370: f(x)= 82.35271646644951
# differential_evolution step 371: f(x)= 82.35271646644951
# differential_evolution step 372: f(x)= 82.35271646644951
# differential_evolution step 373: f(x)= 82.35271646644951
# differential_evolution step 374: f(x)= 82.35271646644951
# differential_evolution step 375: f(x)= 82.35271646644951
# differential_evolution step 376: f(x)= 82.35271646644951
# differential_evolution step 377: f(x)= 82.35271646644951
# differential_evolution step 378: f(x)= 82.35271646644951
# differential_evolution step 379: f(x)= 82.35271646644951
# differential_evolution step 380: f(x)= 82.30192158537055
# differential_evolution step 381: f(x)= 82.30192158537055
# differential_evolution step 382: f(x)= 82.30192158537055
# differential_evolution step 383: f(x)= 82.30192158537055
# differential_evolution step 384: f(x)= 82.30192158537055
# differential_evolution step 385: f(x)= 82.30192158537055
# differential_evolution step 386: f(x)= 82.30192158537055
# differential_evolution step 387: f(x)= 82.30192158537055
# differential_evolution step 388: f(x)= 82.30192158537055
# differential_evolution step 389: f(x)= 82.30192158537055
# differential_evolution step 390: f(x)= 82.30192158537055
# differential_evolution step 391: f(x)= 82.30192158537055
# differential_evolution step 392: f(x)= 82.30192158537055
# differential_evolution step 393: f(x)= 82.30192158537055
# differential_evolution step 394: f(x)= 82.30192158537055
# differential_evolution step 395: f(x)= 82.30192158537055
# differential_evolution step 396: f(x)= 82.30192158537055
# differential_evolution step 397: f(x)= 82.30192158537055
# differential_evolution step 398: f(x)= 82.30192158537055
# differential_evolution step 399: f(x)= 82.30192158537055
# differential_evolution step 400: f(x)= 82.30192158537055
# differential_evolution step 401: f(x)= 82.30192158537055
# differential_evolution step 402: f(x)= 82.30192158537055
# differential_evolution step 403: f(x)= 82.30192158537055
# differential_evolution step 404: f(x)= 82.29043418075034
# differential_evolution step 405: f(x)= 82.29043418075034
# differential_evolution step 406: f(x)= 82.29043418075034
# differential_evolution step 407: f(x)= 82.29043418075034
# differential_evolution step 408: f(x)= 82.29043418075034
# differential_evolution step 409: f(x)= 82.29043418075034
# differential_evolution step 410: f(x)= 82.29043418075034
# differential_evolution step 411: f(x)= 82.29043418075034
# differential_evolution step 412: f(x)= 82.29043418075034
# differential_evolution step 413: f(x)= 82.29043418075034
# differential_evolution step 414: f(x)= 82.29043418075034
# differential_evolution step 415: f(x)= 82.29043418075034
# differential_evolution step 416: f(x)= 82.29043418075034
# differential_evolution step 417: f(x)= 82.29043418075034
# differential_evolution step 418: f(x)= 82.29043418075034
# differential_evolution step 419: f(x)= 82.29043418075034
# differential_evolution step 420: f(x)= 82.29043418075034
# differential_evolution step 421: f(x)= 82.29043418075034
# differential_evolution step 422: f(x)= 82.29043418075034
# differential_evolution step 423: f(x)= 82.29043418075034
# differential_evolution step 424: f(x)= 82.29043418075034
# differential_evolution step 425: f(x)= 82.28232356976852
# differential_evolution step 426: f(x)= 82.28232356976852
# differential_evolution step 427: f(x)= 82.28232356976852
# differential_evolution step 428: f(x)= 82.28232356976852
# differential_evolution step 429: f(x)= 82.28232356976852
# differential_evolution step 430: f(x)= 82.28232356976852
# differential_evolution step 431: f(x)= 82.28232356976852
# differential_evolution step 432: f(x)= 82.28232356976852
# differential_evolution step 433: f(x)= 82.28232356976852
# differential_evolution step 434: f(x)= 82.28232356976852
# differential_evolution step 435: f(x)= 82.28232356976852
# differential_evolution step 436: f(x)= 82.28232356976852
# differential_evolution step 437: f(x)= 82.27253219852827
# differential_evolution step 438: f(x)= 82.27253219852827
# differential_evolution step 439: f(x)= 82.27253219852827
# differential_evolution step 440: f(x)= 82.27253219852827
# differential_evolution step 441: f(x)= 82.27253219852827
# differential_evolution step 442: f(x)= 82.27253219852827
# differential_evolution step 443: f(x)= 82.27253219852827
# differential_evolution step 444: f(x)= 82.27253219852827
# differential_evolution step 445: f(x)= 82.27253219852827
# differential_evolution step 446: f(x)= 82.27253219852827
# differential_evolution step 447: f(x)= 82.27253219852827
# differential_evolution step 448: f(x)= 82.27253219852827
# differential_evolution step 449: f(x)= 82.27253219852827
# differential_evolution step 450: f(x)= 82.27253219852827
# differential_evolution step 451: f(x)= 82.27253219852827
# differential_evolution step 452: f(x)= 82.27253219852827
# differential_evolution step 453: f(x)= 82.27253219852827
# differential_evolution step 454: f(x)= 82.27253219852827
# differential_evolution step 455: f(x)= 82.27253219852827
# differential_evolution step 456: f(x)= 82.27253219852827
# differential_evolution step 457: f(x)= 82.27253219852827
# differential_evolution step 458: f(x)= 82.27253219852827
# differential_evolution step 459: f(x)= 82.27253219852827
# differential_evolution step 460: f(x)= 82.27253219852827
# differential_evolution step 461: f(x)= 82.27253219852827
# differential_evolution step 462: f(x)= 82.27253219852827
# differential_evolution step 463: f(x)= 82.27253219852827
# differential_evolution step 464: f(x)= 82.26979254201062
# differential_evolution step 465: f(x)= 82.26979254201062
# differential_evolution step 466: f(x)= 82.26979254201062
# differential_evolution step 467: f(x)= 82.26603844676993
# differential_evolution step 468: f(x)= 82.26603844676993
# differential_evolution step 469: f(x)= 82.26603844676993
# differential_evolution step 470: f(x)= 82.26603844676993
# differential_evolution step 471: f(x)= 82.26603844676993
# differential_evolution step 472: f(x)= 82.26603844676993
# differential_evolution step 473: f(x)= 82.26603844676993
# differential_evolution step 474: f(x)= 82.26603844676993
# differential_evolution step 475: f(x)= 82.26603844676993
# differential_evolution step 476: f(x)= 82.26603844676993
# differential_evolution step 477: f(x)= 82.26603844676993
# differential_evolution step 478: f(x)= 82.26603844676993
# differential_evolution step 479: f(x)= 82.26603844676993
# differential_evolution step 480: f(x)= 82.26369682514616
# differential_evolution step 481: f(x)= 82.26369682514616
# differential_evolution step 482: f(x)= 82.26369682514616
# differential_evolution step 483: f(x)= 82.26369682514616
# differential_evolution step 484: f(x)= 82.26369682514616
# differential_evolution step 485: f(x)= 82.26369682514616
# differential_evolution step 486: f(x)= 82.26369682514616
# differential_evolution step 487: f(x)= 82.26369682514616
# differential_evolution step 488: f(x)= 82.26366490626383
# differential_evolution step 489: f(x)= 82.26366490626383
# differential_evolution step 490: f(x)= 82.26366490626383
# differential_evolution step 491: f(x)= 82.26366490626383
# differential_evolution step 492: f(x)= 82.26366490626383
# differential_evolution step 493: f(x)= 82.26366490626383
# differential_evolution step 494: f(x)= 82.26366490626383
# differential_evolution step 495: f(x)= 82.26366490626383
# differential_evolution step 496: f(x)= 82.26034217936655
# differential_evolution step 497: f(x)= 82.26034217936655
# differential_evolution step 498: f(x)= 82.26034217936655
# differential_evolution step 499: f(x)= 82.26034217936655
# differential_evolution step 500: f(x)= 82.26034217936655
# differential_evolution step 501: f(x)= 82.26034217936655
# differential_evolution step 502: f(x)= 82.26034217936655
# differential_evolution step 503: f(x)= 82.26034217936655
# differential_evolution step 504: f(x)= 82.26034217936655
# differential_evolution step 505: f(x)= 82.26034217936655
# differential_evolution step 506: f(x)= 82.26034217936655
# differential_evolution step 507: f(x)= 82.26034217936655
# differential_evolution step 508: f(x)= 82.25969565651941
# differential_evolution step 509: f(x)= 82.25797644020521
# differential_evolution step 510: f(x)= 82.25797644020521
# differential_evolution step 511: f(x)= 82.25797644020521
# differential_evolution step 512: f(x)= 82.25797644020521
# differential_evolution step 513: f(x)= 82.25797644020521
# differential_evolution step 514: f(x)= 82.25797644020521
# differential_evolution step 515: f(x)= 82.25797644020521
# differential_evolution step 516: f(x)= 82.25797644020521
# differential_evolution step 517: f(x)= 82.25688189927516
# differential_evolution step 518: f(x)= 82.25688189927516
# differential_evolution step 519: f(x)= 82.25688189927516
# differential_evolution step 520: f(x)= 82.25688189927516
# differential_evolution step 521: f(x)= 82.25688189927516
# differential_evolution step 522: f(x)= 82.25688189927516
# differential_evolution step 523: f(x)= 82.25688189927516
# differential_evolution step 524: f(x)= 82.25688189927516
# differential_evolution step 525: f(x)= 82.25688189927516
# differential_evolution step 526: f(x)= 82.25688189927516
# differential_evolution step 527: f(x)= 82.25688189927516
# differential_evolution step 528: f(x)= 82.25688189927516
# differential_evolution step 529: f(x)= 82.25688189927516
# differential_evolution step 530: f(x)= 82.25688189927516
# differential_evolution step 531: f(x)= 82.25688189927516
# differential_evolution step 532: f(x)= 82.25688189927516
# differential_evolution step 533: f(x)= 82.25688189927516
# differential_evolution step 534: f(x)= 82.25688189927516
# differential_evolution step 535: f(x)= 82.25688189927516
# differential_evolution step 536: f(x)= 82.25688189927516
# differential_evolution step 537: f(x)= 82.25688189927516
# differential_evolution step 538: f(x)= 82.25552674301272
# differential_evolution step 539: f(x)= 82.25552674301272
# differential_evolution step 540: f(x)= 82.25552674301272
# differential_evolution step 541: f(x)= 82.25552674301272
# differential_evolution step 542: f(x)= 82.25552674301272
# differential_evolution step 543: f(x)= 82.25552674301272
# differential_evolution step 544: f(x)= 82.25552674301272
# differential_evolution step 545: f(x)= 82.25552674301272
# differential_evolution step 546: f(x)= 82.25552674301272
# differential_evolution step 547: f(x)= 82.25552674301272
# differential_evolution step 548: f(x)= 82.25552674301272
# differential_evolution step 549: f(x)= 82.25441138800954
# differential_evolution step 550: f(x)= 82.25441138800954
# differential_evolution step 551: f(x)= 82.25441138800954
# differential_evolution step 552: f(x)= 82.25426086366676
# differential_evolution step 553: f(x)= 82.25426086366676
# differential_evolution step 554: f(x)= 82.25426086366676
# differential_evolution step 555: f(x)= 82.25426086366676
# differential_evolution step 556: f(x)= 82.25426086366676
# differential_evolution step 557: f(x)= 82.25240182257151
# differential_evolution step 558: f(x)= 82.25240182257151
# differential_evolution step 559: f(x)= 82.25240182257151
# differential_evolution step 560: f(x)= 82.25240182257151
# differential_evolution step 561: f(x)= 82.25240182257151
# differential_evolution step 562: f(x)= 82.25240182257151
# differential_evolution step 563: f(x)= 82.25240182257151
# differential_evolution step 564: f(x)= 82.25240182257151
# differential_evolution step 565: f(x)= 82.25240182257151
# differential_evolution step 566: f(x)= 82.25240182257151
# differential_evolution step 567: f(x)= 82.25240182257151
# differential_evolution step 568: f(x)= 82.25240182257151
# differential_evolution step 569: f(x)= 82.25240182257151
# differential_evolution step 570: f(x)= 82.25240182257151
# differential_evolution step 571: f(x)= 82.25240182257151
# differential_evolution step 572: f(x)= 82.25240182257151
# differential_evolution step 573: f(x)= 82.25240182257151
# differential_evolution step 574: f(x)= 82.25240182257151
# differential_evolution step 575: f(x)= 82.2508980762958
# differential_evolution step 576: f(x)= 82.2508980762958
# differential_evolution step 577: f(x)= 82.2508980762958
# differential_evolution step 578: f(x)= 82.25003103885187
# differential_evolution step 579: f(x)= 82.25003103885187
# differential_evolution step 580: f(x)= 82.25003103885187
# differential_evolution step 581: f(x)= 82.25003103885187
# differential_evolution step 582: f(x)= 82.25003103885187
# differential_evolution step 583: f(x)= 82.25003103885187
# differential_evolution step 584: f(x)= 82.25003103885187
# differential_evolution step 585: f(x)= 82.25003103885187
# differential_evolution step 586: f(x)= 82.25003103885187
# differential_evolution step 587: f(x)= 82.25003103885187
# differential_evolution step 588: f(x)= 82.25003103885187
# differential_evolution step 589: f(x)= 82.25003103885187
# differential_evolution step 590: f(x)= 82.25003103885187
# differential_evolution step 591: f(x)= 82.25003103885187
# differential_evolution step 592: f(x)= 82.25003103885187
# differential_evolution step 593: f(x)= 82.25003103885187
# differential_evolution step 594: f(x)= 82.25003103885187
# differential_evolution step 595: f(x)= 82.25003103885187
# differential_evolution step 596: f(x)= 82.25003103885187
# differential_evolution step 597: f(x)= 82.25003103885187
# differential_evolution step 598: f(x)= 82.25003103885187
# differential_evolution step 599: f(x)= 82.24993506503075
# differential_evolution step 600: f(x)= 82.24993506503075
# differential_evolution step 601: f(x)= 82.24993506503075
# differential_evolution step 602: f(x)= 82.24993506503075
# differential_evolution step 603: f(x)= 82.24993506503075
# differential_evolution step 604: f(x)= 82.24993506503075
# differential_evolution step 605: f(x)= 82.24993506503075
# differential_evolution step 606: f(x)= 82.24993506503075
# differential_evolution step 607: f(x)= 82.24993506503075
# differential_evolution step 608: f(x)= 82.24993506503075
# differential_evolution step 609: f(x)= 82.24993506503075
# differential_evolution step 610: f(x)= 82.24993506503075
# differential_evolution step 611: f(x)= 82.24993506503075
# differential_evolution step 612: f(x)= 82.24993506503075
# differential_evolution step 613: f(x)= 82.24993506503075
# differential_evolution step 614: f(x)= 82.24993506503075
# differential_evolution step 615: f(x)= 82.24993506503075
# differential_evolution step 616: f(x)= 82.24993506503075
# differential_evolution step 617: f(x)= 82.24993506503075
# differential_evolution step 618: f(x)= 82.24912455045664
# differential_evolution step 619: f(x)= 82.24912455045664
# differential_evolution step 620: f(x)= 82.24912455045664
# differential_evolution step 621: f(x)= 82.24912455045664
# differential_evolution step 622: f(x)= 82.24912455045664
# differential_evolution step 623: f(x)= 82.24912455045664
# differential_evolution step 624: f(x)= 82.24912455045664
# differential_evolution step 625: f(x)= 82.24912455045664
# differential_evolution step 626: f(x)= 82.24912455045664
# differential_evolution step 627: f(x)= 82.24912455045664
# differential_evolution step 628: f(x)= 82.24912455045664
# differential_evolution step 629: f(x)= 82.24912455045664
# differential_evolution step 630: f(x)= 82.24912455045664
# differential_evolution step 631: f(x)= 82.24912455045664
# differential_evolution step 632: f(x)= 82.24912455045664
# differential_evolution step 633: f(x)= 82.24912455045664
# differential_evolution step 634: f(x)= 82.24912455045664
# differential_evolution step 635: f(x)= 82.24912455045664
# differential_evolution step 636: f(x)= 82.24912455045664
# differential_evolution step 637: f(x)= 82.24912455045664
# differential_evolution step 638: f(x)= 82.24912455045664
# differential_evolution step 639: f(x)= 82.24912455045664
# differential_evolution step 640: f(x)= 82.24912455045664
# differential_evolution step 641: f(x)= 82.24912455045664
# differential_evolution step 642: f(x)= 82.24912455045664
# differential_evolution step 643: f(x)= 82.24907451323989
# differential_evolution step 644: f(x)= 82.24907451323989
# differential_evolution step 645: f(x)= 82.24907451323989
# differential_evolution step 646: f(x)= 82.24907451323989
# differential_evolution step 647: f(x)= 82.24907451323989
# differential_evolution step 648: f(x)= 82.24907451323989
# differential_evolution step 649: f(x)= 82.24907451323989
# differential_evolution step 650: f(x)= 82.24907451323989
# differential_evolution step 651: f(x)= 82.24907451323989
# differential_evolution step 652: f(x)= 82.24907451323989
# differential_evolution step 653: f(x)= 82.24907451323989
# differential_evolution step 654: f(x)= 82.24907451323989
# differential_evolution step 655: f(x)= 82.24907451323989
# differential_evolution step 656: f(x)= 82.24894545472729
# differential_evolution step 657: f(x)= 82.24894545472729
# differential_evolution step 658: f(x)= 82.24894545472729
# differential_evolution step 659: f(x)= 82.24894545472729
# differential_evolution step 660: f(x)= 82.24894545472729
# differential_evolution step 661: f(x)= 82.24894545472729
# differential_evolution step 662: f(x)= 82.24870505905871
# differential_evolution step 663: f(x)= 82.24870505905871
# differential_evolution step 664: f(x)= 82.24870505905871
# differential_evolution step 665: f(x)= 82.24870505905871
# differential_evolution step 666: f(x)= 82.24870505905871
# differential_evolution step 667: f(x)= 82.24870505905871
# differential_evolution step 668: f(x)= 82.24870505905871
# differential_evolution step 669: f(x)= 82.24870505905871
# differential_evolution step 670: f(x)= 82.24855091436041
# differential_evolution step 671: f(x)= 82.24855091436041
# differential_evolution step 672: f(x)= 82.24855091436041
# differential_evolution step 673: f(x)= 82.24855091436041
# differential_evolution step 674: f(x)= 82.24855091436041
# differential_evolution step 675: f(x)= 82.24855091436041
# differential_evolution step 676: f(x)= 82.24855091436041
# differential_evolution step 677: f(x)= 82.24855091436041
# differential_evolution step 678: f(x)= 82.24855091436041
# differential_evolution step 679: f(x)= 82.24855091436041
# differential_evolution step 680: f(x)= 82.24855091436041
# differential_evolution step 681: f(x)= 82.24855091436041
# differential_evolution step 682: f(x)= 82.24855091436041
# differential_evolution step 683: f(x)= 82.24855091436041
# differential_evolution step 684: f(x)= 82.24855091436041
# differential_evolution step 685: f(x)= 82.24855091436041
# differential_evolution step 686: f(x)= 82.24855091436041
# differential_evolution step 687: f(x)= 82.24855091436041
# differential_evolution step 688: f(x)= 82.24855091436041
# differential_evolution step 689: f(x)= 82.24855091436041
# differential_evolution step 690: f(x)= 82.24855091436041
# differential_evolution step 691: f(x)= 82.24855091436041
# differential_evolution step 692: f(x)= 82.24855091436041
# differential_evolution step 693: f(x)= 82.24855091436041
# differential_evolution step 694: f(x)= 82.24855091436041
# differential_evolution step 695: f(x)= 82.24855091436041
# differential_evolution step 696: f(x)= 82.24855091436041
# differential_evolution step 697: f(x)= 82.24854984130872
# differential_evolution step 698: f(x)= 82.24854984130872
# differential_evolution step 699: f(x)= 82.24854984130872
# differential_evolution step 700: f(x)= 82.24854984130872
# differential_evolution step 701: f(x)= 82.24854984130872
# differential_evolution step 702: f(x)= 82.24854984130872
# differential_evolution step 703: f(x)= 82.24854984130872
# differential_evolution step 704: f(x)= 82.24854984130872
# differential_evolution step 705: f(x)= 82.24854984130872
# differential_evolution step 706: f(x)= 82.24854984130872
# differential_evolution step 707: f(x)= 82.24854984130872
# differential_evolution step 708: f(x)= 82.24854984130872
# differential_evolution step 709: f(x)= 82.24838798475731
# differential_evolution step 710: f(x)= 82.24838798475731
# differential_evolution step 711: f(x)= 82.24838798475731
# differential_evolution step 712: f(x)= 82.24823503430767
# differential_evolution step 713: f(x)= 82.24822004799884
# differential_evolution step 714: f(x)= 82.24822004799884
# differential_evolution step 715: f(x)= 82.24822004799884
# differential_evolution step 716: f(x)= 82.24822004799884
# differential_evolution step 717: f(x)= 82.24822004799884
# differential_evolution step 718: f(x)= 82.24807535594891
# differential_evolution step 719: f(x)= 82.24807535594891
# differential_evolution step 720: f(x)= 82.24807535594891
# differential_evolution step 721: f(x)= 82.24807535594891
# differential_evolution step 722: f(x)= 82.24807535594891
# differential_evolution step 723: f(x)= 82.24807535594891
# differential_evolution step 724: f(x)= 82.24807535594891
# differential_evolution step 725: f(x)= 82.24787652316581
# differential_evolution step 726: f(x)= 82.24787652316581
# differential_evolution step 727: f(x)= 82.24787652316581
# differential_evolution step 728: f(x)= 82.24787652316581
# differential_evolution step 729: f(x)= 82.24787652316581
# differential_evolution step 730: f(x)= 82.24787652316581
# differential_evolution step 731: f(x)= 82.24787652316581
# differential_evolution step 732: f(x)= 82.24787652316581
# differential_evolution step 733: f(x)= 82.24787652316581
# differential_evolution step 734: f(x)= 82.24787652316581
# differential_evolution step 735: f(x)= 82.24787652316581
# differential_evolution step 736: f(x)= 82.24787652316581
# differential_evolution step 737: f(x)= 82.24787652316581
# differential_evolution step 738: f(x)= 82.24787652316581
# differential_evolution step 739: f(x)= 82.24787652316581
# differential_evolution step 740: f(x)= 82.24778669024288
# differential_evolution step 741: f(x)= 82.24778669024288
# differential_evolution step 742: f(x)= 82.24778669024288
# differential_evolution step 743: f(x)= 82.24778669024288
# differential_evolution step 744: f(x)= 82.247773344625
# differential_evolution step 745: f(x)= 82.247773344625
# differential_evolution step 746: f(x)= 82.247773344625
# differential_evolution step 747: f(x)= 82.247773344625
# differential_evolution step 748: f(x)= 82.247773344625
# differential_evolution step 749: f(x)= 82.247773344625
# differential_evolution step 750: f(x)= 82.247773344625
# differential_evolution step 751: f(x)= 82.247773344625
# differential_evolution step 752: f(x)= 82.247773344625
# differential_evolution step 753: f(x)= 82.247773344625
# differential_evolution step 754: f(x)= 82.24768812358441
# differential_evolution step 755: f(x)= 82.24768812358441
# differential_evolution step 756: f(x)= 82.24768812358441
# differential_evolution step 757: f(x)= 82.24768812358441
# differential_evolution step 758: f(x)= 82.24764675886108
# differential_evolution step 759: f(x)= 82.24764675886108
# differential_evolution step 760: f(x)= 82.24757829827821
# differential_evolution step 761: f(x)= 82.24757829827821
# differential_evolution step 762: f(x)= 82.24757829827821
# differential_evolution step 763: f(x)= 82.24757829827821
# differential_evolution step 764: f(x)= 82.24757829827821
# differential_evolution step 765: f(x)= 82.24757829827821
# differential_evolution step 766: f(x)= 82.24757829827821
# differential_evolution step 767: f(x)= 82.24757829827821
# differential_evolution step 768: f(x)= 82.24757829827821
# differential_evolution step 769: f(x)= 82.24757829827821
# differential_evolution step 770: f(x)= 82.24757829827821
# differential_evolution step 771: f(x)= 82.24757829827821
# differential_evolution step 772: f(x)= 82.24757829827821
# differential_evolution step 773: f(x)= 82.24757829827821
# differential_evolution step 774: f(x)= 82.24757829827821
# differential_evolution step 775: f(x)= 82.24757829827821
# differential_evolution step 776: f(x)= 82.24757829827821
# differential_evolution step 777: f(x)= 82.24757829827821
# differential_evolution step 778: f(x)= 82.24757829827821
# differential_evolution step 779: f(x)= 82.24757829827821
# differential_evolution step 780: f(x)= 82.24757829827821
# differential_evolution step 781: f(x)= 82.24757829827821
# differential_evolution step 782: f(x)= 82.24757829827821
# differential_evolution step 783: f(x)= 82.24757829827821
# differential_evolution step 784: f(x)= 82.24757829827821
# differential_evolution step 785: f(x)= 82.24757829827821
# differential_evolution step 786: f(x)= 82.24757829827821
# differential_evolution step 787: f(x)= 82.24757829827821
# differential_evolution step 788: f(x)= 82.24757829827821
# differential_evolution step 789: f(x)= 82.24757829827821
# differential_evolution step 790: f(x)= 82.24757829827821
# differential_evolution step 791: f(x)= 82.24757829827821
# differential_evolution step 792: f(x)= 82.24757829827821
# differential_evolution step 793: f(x)= 82.24757829827821
# differential_evolution step 794: f(x)= 82.24757829827821
# differential_evolution step 795: f(x)= 82.24757829827821
# differential_evolution step 796: f(x)= 82.24757829827821
# differential_evolution step 797: f(x)= 82.24757829827821
# differential_evolution step 798: f(x)= 82.24757409059096
# differential_evolution step 799: f(x)= 82.24757409059096
# differential_evolution step 800: f(x)= 82.24757409059096
# differential_evolution step 801: f(x)= 82.24757409059096
# differential_evolution step 802: f(x)= 82.24757237280944
# differential_evolution step 803: f(x)= 82.24757237280944
# differential_evolution step 804: f(x)= 82.24757237280944
# differential_evolution step 805: f(x)= 82.24757237280944
# differential_evolution step 806: f(x)= 82.24757237280944
# differential_evolution step 807: f(x)= 82.24755090230143
# differential_evolution step 808: f(x)= 82.24755090230143
# differential_evolution step 809: f(x)= 82.24755090230143
# differential_evolution step 810: f(x)= 82.24754909019143
# differential_evolution step 811: f(x)= 82.24754909019143
# differential_evolution step 812: f(x)= 82.24754909019143
# differential_evolution step 813: f(x)= 82.24754909019143
# differential_evolution step 814: f(x)= 82.24754909019143
# differential_evolution step 815: f(x)= 82.24754909019143
# differential_evolution step 816: f(x)= 82.24754909019143
# differential_evolution step 817: f(x)= 82.24754909019143
# differential_evolution step 818: f(x)= 82.24754909019143
# differential_evolution step 819: f(x)= 82.24750326696312
# differential_evolution step 820: f(x)= 82.24750326696312
# differential_evolution step 821: f(x)= 82.24750326696312
# differential_evolution step 822: f(x)= 82.24749345981851
# differential_evolution step 823: f(x)= 82.24749345981851
# differential_evolution step 824: f(x)= 82.24749345981851
# differential_evolution step 825: f(x)= 82.24749345981851
# differential_evolution step 826: f(x)= 82.24749345981851
# differential_evolution step 827: f(x)= 82.24749345981851
# differential_evolution step 828: f(x)= 82.24749345981851
# differential_evolution step 829: f(x)= 82.24749345981851
# differential_evolution step 830: f(x)= 82.24749345981851
# differential_evolution step 831: f(x)= 82.24749345981851
# differential_evolution step 832: f(x)= 82.24749345981851
# differential_evolution step 833: f(x)= 82.24749345981851
# differential_evolution step 834: f(x)= 82.24749345981851
# differential_evolution step 835: f(x)= 82.24749345981851
# differential_evolution step 836: f(x)= 82.24749345981851
# differential_evolution step 837: f(x)= 82.24749345981851
# differential_evolution step 838: f(x)= 82.24749345981851
# differential_evolution step 839: f(x)= 82.24749345981851
# differential_evolution step 840: f(x)= 82.24749345981851
# differential_evolution step 841: f(x)= 82.24749345981851
# differential_evolution step 842: f(x)= 82.24749345981851
# differential_evolution step 843: f(x)= 82.24749345981851
# differential_evolution step 844: f(x)= 82.24749345981851
# differential_evolution step 845: f(x)= 82.24749345981851
# differential_evolution step 846: f(x)= 82.24747622593641
# differential_evolution step 847: f(x)= 82.24747622593641
# differential_evolution step 848: f(x)= 82.24747622593641
# differential_evolution step 849: f(x)= 82.24747622593641
# differential_evolution step 850: f(x)= 82.24747622593641
# differential_evolution step 851: f(x)= 82.24747622593641
# differential_evolution step 852: f(x)= 82.24747622593641
# differential_evolution step 853: f(x)= 82.2474567504322
# differential_evolution step 854: f(x)= 82.2474567504322
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.4632, r_e=9.1914, n=1.2386, x_0=44.2792
# Sérsic 2: I_e=0.6770, r_e=21.1378, n=2.5478, x_0=51.5424
# Sérsic 3: I_e=10.0000, r_e=4.5085, n=0.9485, x_0=59.5384
# Chi quadro minimo: 82.2474567504322
# True

# %%
# Plots:
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = radial_profile_error_OIII)#, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, radial_profile_error_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=2.0534, r_e=8.8059, n=1.0959, x_0=44.7114
# Sérsic 2: I_e=0.1191, r_e=49.4186, n=3.9815, x_0=51.5424
# Sérsic 3: I_e=10.2813, r_e=4.7796, n=0.9374, x_0=59.1818
# [2.07013644e-01 5.05397232e-01 6.51230029e-02 1.49399734e-01
#  1.94185132e-01 4.46102690e+01 1.88465179e+00 1.70602736e-04
#  3.80410795e-01 1.44483653e-01 3.16007466e-02 4.42612916e-02]
# 26.012835576000096

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 189725.36162371997
# differential_evolution step 2: f(x)= 97950.26586496955
# differential_evolution step 3: f(x)= 97950.26586496955
# differential_evolution step 4: f(x)= 79524.71614109227
# differential_evolution step 5: f(x)= 47023.481801592345
# differential_evolution step 6: f(x)= 47023.481801592345
# differential_evolution step 7: f(x)= 47023.481801592345
# differential_evolution step 8: f(x)= 47023.481801592345
# differential_evolution step 9: f(x)= 47023.481801592345
# differential_evolution step 10: f(x)= 37310.8229468055
# differential_evolution step 11: f(x)= 37310.8229468055
# differential_evolution step 12: f(x)= 30119.24490340297
# differential_evolution step 13: f(x)= 30119.24490340297
# differential_evolution step 14: f(x)= 30119.24490340297
# differential_evolution step 15: f(x)= 30119.24490340297
# differential_evolution step 16: f(x)= 29345.679931104944
# differential_evolution step 17: f(x)= 24839.8709273911
# differential_evolution step 18: f(x)= 22084.57963115009
# differential_evolution step 19: f(x)= 22084.57963115009
# differential_evolution step 20: f(x)= 21255.38379904328
# differential_evolution step 21: f(x)= 21255.38379904328
# differential_evolution step 22: f(x)= 21255.38379904328
# differential_evolution step 23: f(x)= 21255.38379904328
# differential_evolution step 24: f(x)= 16472.71857351245
# differential_evolution step 25: f(x)= 16472.71857351245
# differential_evolution step 26: f(x)= 16472.71857351245
# differential_evolution step 27: f(x)= 16472.71857351245
# differential_evolution step 28: f(x)= 16472.71857351245
# differential_evolution step 29: f(x)= 16472.71857351245
# differential_evolution step 30: f(x)= 16472.71857351245
# differential_evolution step 31: f(x)= 16472.71857351245
# differential_evolution step 32: f(x)= 15397.577064301591
# differential_evolution step 33: f(x)= 15397.577064301591
# differential_evolution step 34: f(x)= 14315.454820207673
# differential_evolution step 35: f(x)= 14315.454820207673
# differential_evolution step 36: f(x)= 14315.454820207673
# differential_evolution step 37: f(x)= 14315.454820207673
# differential_evolution step 38: f(x)= 14315.454820207673
# differential_evolution step 39: f(x)= 14315.454820207673
# differential_evolution step 40: f(x)= 9068.197136628234
# differential_evolution step 41: f(x)= 9068.197136628234
# differential_evolution step 42: f(x)= 9068.197136628234
# differential_evolution step 43: f(x)= 9068.197136628234
# differential_evolution step 44: f(x)= 9068.197136628234
# differential_evolution step 45: f(x)= 9068.197136628234
# differential_evolution step 46: f(x)= 9068.197136628234
# differential_evolution step 47: f(x)= 9068.197136628234
# differential_evolution step 48: f(x)= 9068.197136628234
# differential_evolution step 49: f(x)= 9068.197136628234
# differential_evolution step 50: f(x)= 9068.197136628234
# differential_evolution step 51: f(x)= 8884.129893758554
# differential_evolution step 52: f(x)= 8884.129893758554
# differential_evolution step 53: f(x)= 8884.129893758554
# differential_evolution step 54: f(x)= 8884.129893758554
# differential_evolution step 55: f(x)= 8884.129893758554
# differential_evolution step 56: f(x)= 8884.129893758554
# differential_evolution step 57: f(x)= 8884.129893758554
# differential_evolution step 58: f(x)= 8884.129893758554
# differential_evolution step 59: f(x)= 8884.129893758554
# differential_evolution step 60: f(x)= 8884.129893758554
# differential_evolution step 61: f(x)= 8884.129893758554
# differential_evolution step 62: f(x)= 7459.644165129572
# differential_evolution step 63: f(x)= 7459.644165129572
# differential_evolution step 64: f(x)= 7459.644165129572
# differential_evolution step 65: f(x)= 7459.644165129572
# differential_evolution step 66: f(x)= 7459.644165129572
# differential_evolution step 67: f(x)= 7459.644165129572
# differential_evolution step 68: f(x)= 7459.644165129572
# differential_evolution step 69: f(x)= 7459.644165129572
# differential_evolution step 70: f(x)= 7459.644165129572
# differential_evolution step 71: f(x)= 7459.644165129572
# differential_evolution step 72: f(x)= 7459.644165129572
# differential_evolution step 73: f(x)= 7459.644165129572
# differential_evolution step 74: f(x)= 7459.644165129572
# differential_evolution step 75: f(x)= 7459.644165129572
# differential_evolution step 76: f(x)= 7459.644165129572
# differential_evolution step 77: f(x)= 7459.644165129572
# differential_evolution step 78: f(x)= 7459.644165129572
# differential_evolution step 79: f(x)= 7459.644165129572
# differential_evolution step 80: f(x)= 7184.500116494653
# differential_evolution step 81: f(x)= 7184.500116494653
# differential_evolution step 82: f(x)= 7184.500116494653
# differential_evolution step 83: f(x)= 7184.500116494653
# differential_evolution step 84: f(x)= 7184.500116494653
# differential_evolution step 85: f(x)= 6624.757578193265
# differential_evolution step 86: f(x)= 6624.757578193265
# differential_evolution step 87: f(x)= 6624.757578193265
# differential_evolution step 88: f(x)= 6624.757578193265
# differential_evolution step 89: f(x)= 6624.757578193265
# differential_evolution step 90: f(x)= 6624.757578193265
# differential_evolution step 91: f(x)= 6457.64020057438
# differential_evolution step 92: f(x)= 6457.64020057438
# differential_evolution step 93: f(x)= 6457.64020057438
# differential_evolution step 94: f(x)= 6457.64020057438
# differential_evolution step 95: f(x)= 6457.64020057438
# differential_evolution step 96: f(x)= 6457.64020057438
# differential_evolution step 97: f(x)= 6457.64020057438
# differential_evolution step 98: f(x)= 6457.64020057438
# differential_evolution step 99: f(x)= 6457.64020057438
# differential_evolution step 100: f(x)= 6457.64020057438
# differential_evolution step 101: f(x)= 6457.64020057438
# differential_evolution step 102: f(x)= 6457.64020057438
# differential_evolution step 103: f(x)= 6457.64020057438
# differential_evolution step 104: f(x)= 6457.64020057438
# differential_evolution step 105: f(x)= 6457.64020057438
# differential_evolution step 106: f(x)= 6457.64020057438
# differential_evolution step 107: f(x)= 6457.64020057438
# differential_evolution step 108: f(x)= 6450.690215522086
# differential_evolution step 109: f(x)= 6450.690215522086
# differential_evolution step 110: f(x)= 6450.690215522086
# differential_evolution step 111: f(x)= 6450.690215522086
# differential_evolution step 112: f(x)= 6429.92644178862
# differential_evolution step 113: f(x)= 6261.117686084759
# differential_evolution step 114: f(x)= 6055.525950625272
# differential_evolution step 115: f(x)= 6055.525950625272
# differential_evolution step 116: f(x)= 6055.525950625272
# differential_evolution step 117: f(x)= 6055.525950625272
# differential_evolution step 118: f(x)= 6055.525950625272
# differential_evolution step 119: f(x)= 6055.525950625272
# differential_evolution step 120: f(x)= 6055.525950625272
# differential_evolution step 121: f(x)= 6055.525950625272
# differential_evolution step 122: f(x)= 6055.525950625272
# differential_evolution step 123: f(x)= 6055.525950625272
# differential_evolution step 124: f(x)= 6055.525950625272
# differential_evolution step 125: f(x)= 6055.525950625272
# differential_evolution step 126: f(x)= 6055.525950625272
# differential_evolution step 127: f(x)= 5912.307769736877
# differential_evolution step 128: f(x)= 5757.300316578206
# differential_evolution step 129: f(x)= 5757.300316578206
# differential_evolution step 130: f(x)= 5757.300316578206
# differential_evolution step 131: f(x)= 5757.300316578206
# differential_evolution step 132: f(x)= 5712.639493909552
# differential_evolution step 133: f(x)= 5712.639493909552
# differential_evolution step 134: f(x)= 5712.639493909552
# differential_evolution step 135: f(x)= 5712.639493909552
# differential_evolution step 136: f(x)= 5632.226538565383
# differential_evolution step 137: f(x)= 5632.226538565383
# differential_evolution step 138: f(x)= 5632.226538565383
# differential_evolution step 139: f(x)= 5632.226538565383
# differential_evolution step 140: f(x)= 5611.986427094675
# differential_evolution step 141: f(x)= 5611.986427094675
# differential_evolution step 142: f(x)= 5611.986427094675
# differential_evolution step 143: f(x)= 5606.275244369931
# differential_evolution step 144: f(x)= 5493.950679803616
# differential_evolution step 145: f(x)= 5493.950679803616
# differential_evolution step 146: f(x)= 5493.950679803616
# differential_evolution step 147: f(x)= 5493.950679803616
# differential_evolution step 148: f(x)= 5493.950679803616
# differential_evolution step 149: f(x)= 5493.950679803616
# differential_evolution step 150: f(x)= 5493.950679803616
# differential_evolution step 151: f(x)= 5493.950679803616
# differential_evolution step 152: f(x)= 5493.950679803616
# differential_evolution step 153: f(x)= 5493.950679803616
# differential_evolution step 154: f(x)= 5489.088446459343
# differential_evolution step 155: f(x)= 5424.865978799377
# differential_evolution step 156: f(x)= 5424.865978799377
# differential_evolution step 157: f(x)= 5424.865978799377
# differential_evolution step 158: f(x)= 5424.865978799377
# differential_evolution step 159: f(x)= 5424.865978799377
# differential_evolution step 160: f(x)= 5424.865978799377
# differential_evolution step 161: f(x)= 5424.865978799377
# differential_evolution step 162: f(x)= 5424.865978799377
# differential_evolution step 163: f(x)= 5424.865978799377
# differential_evolution step 164: f(x)= 5424.865978799377
# differential_evolution step 165: f(x)= 5424.865978799377
# differential_evolution step 166: f(x)= 5422.519400251585
# differential_evolution step 167: f(x)= 5422.519400251585
# differential_evolution step 168: f(x)= 5422.519400251585
# differential_evolution step 169: f(x)= 5422.519400251585
# differential_evolution step 170: f(x)= 5422.519400251585
# differential_evolution step 171: f(x)= 5422.519400251585
# differential_evolution step 172: f(x)= 5422.519400251585
# differential_evolution step 173: f(x)= 5422.519400251585
# differential_evolution step 174: f(x)= 5422.519400251585
# differential_evolution step 175: f(x)= 5422.519400251585
# differential_evolution step 176: f(x)= 5398.38470552869
# differential_evolution step 177: f(x)= 5398.38470552869
# differential_evolution step 178: f(x)= 5398.38470552869
# differential_evolution step 179: f(x)= 5398.38470552869
# differential_evolution step 180: f(x)= 5398.38470552869
# differential_evolution step 181: f(x)= 5398.38470552869
# differential_evolution step 182: f(x)= 5398.38470552869
# differential_evolution step 183: f(x)= 5398.38470552869
# differential_evolution step 184: f(x)= 5229.052340550545
# differential_evolution step 185: f(x)= 5229.052340550545
# differential_evolution step 186: f(x)= 5229.052340550545
# differential_evolution step 187: f(x)= 5229.052340550545
# differential_evolution step 188: f(x)= 5229.052340550545
# differential_evolution step 189: f(x)= 5229.052340550545
# differential_evolution step 190: f(x)= 5229.052340550545
# differential_evolution step 191: f(x)= 5229.052340550545
# differential_evolution step 192: f(x)= 5229.052340550545
# differential_evolution step 193: f(x)= 5229.052340550545
# differential_evolution step 194: f(x)= 5229.052340550545
# differential_evolution step 195: f(x)= 5229.052340550545
# differential_evolution step 196: f(x)= 5229.052340550545
# differential_evolution step 197: f(x)= 5229.052340550545
# differential_evolution step 198: f(x)= 5196.744519170537
# differential_evolution step 199: f(x)= 5196.744519170537
# differential_evolution step 200: f(x)= 5196.744519170537
# differential_evolution step 201: f(x)= 5196.744519170537
# differential_evolution step 202: f(x)= 5196.744519170537
# differential_evolution step 203: f(x)= 5178.029562585581
# differential_evolution step 204: f(x)= 5178.029562585581
# differential_evolution step 205: f(x)= 5169.826204573394
# differential_evolution step 206: f(x)= 5169.826204573394
# differential_evolution step 207: f(x)= 5169.826204573394
# differential_evolution step 208: f(x)= 5169.826204573394
# differential_evolution step 209: f(x)= 5169.826204573394
# differential_evolution step 210: f(x)= 5169.826204573394
# differential_evolution step 211: f(x)= 5169.826204573394
# differential_evolution step 212: f(x)= 5169.0458784071
# differential_evolution step 213: f(x)= 5169.0458784071
# differential_evolution step 214: f(x)= 5169.0458784071
# differential_evolution step 215: f(x)= 5169.0458784071
# differential_evolution step 216: f(x)= 5108.237831340325
# differential_evolution step 217: f(x)= 5108.237831340325
# differential_evolution step 218: f(x)= 5108.237831340325
# differential_evolution step 219: f(x)= 5108.237831340325
# differential_evolution step 220: f(x)= 5108.237831340325
# differential_evolution step 221: f(x)= 5046.875347771202
# differential_evolution step 222: f(x)= 5046.875347771202
# differential_evolution step 223: f(x)= 5046.875347771202
# differential_evolution step 224: f(x)= 5046.875347771202
# differential_evolution step 225: f(x)= 5046.875347771202
# differential_evolution step 226: f(x)= 5046.875347771202
# differential_evolution step 227: f(x)= 5046.875347771202
# differential_evolution step 228: f(x)= 5046.875347771202
# differential_evolution step 229: f(x)= 5046.875347771202
# differential_evolution step 230: f(x)= 5046.875347771202
# differential_evolution step 231: f(x)= 5046.875347771202
# differential_evolution step 232: f(x)= 5046.875347771202
# differential_evolution step 233: f(x)= 5046.875347771202
# differential_evolution step 234: f(x)= 5046.875347771202
# differential_evolution step 235: f(x)= 5046.875347771202
# differential_evolution step 236: f(x)= 4995.568039063988
# differential_evolution step 237: f(x)= 4995.568039063988
# differential_evolution step 238: f(x)= 4995.568039063988
# differential_evolution step 239: f(x)= 4995.568039063988
# differential_evolution step 240: f(x)= 4995.568039063988
# differential_evolution step 241: f(x)= 4995.568039063988
# differential_evolution step 242: f(x)= 4995.568039063988
# differential_evolution step 243: f(x)= 4995.568039063988
# differential_evolution step 244: f(x)= 4995.568039063988
# differential_evolution step 245: f(x)= 4995.568039063988
# differential_evolution step 246: f(x)= 4995.568039063988
# differential_evolution step 247: f(x)= 4995.568039063988
# differential_evolution step 248: f(x)= 4995.568039063988
# differential_evolution step 249: f(x)= 4995.568039063988
# differential_evolution step 250: f(x)= 4995.568039063988
# differential_evolution step 251: f(x)= 4995.568039063988
# differential_evolution step 252: f(x)= 4995.568039063988
# differential_evolution step 253: f(x)= 4995.568039063988
# differential_evolution step 254: f(x)= 4995.568039063988
# differential_evolution step 255: f(x)= 4995.568039063988
# differential_evolution step 256: f(x)= 4995.568039063988
# differential_evolution step 257: f(x)= 4995.568039063988
# differential_evolution step 258: f(x)= 4995.568039063988
# differential_evolution step 259: f(x)= 4995.568039063988
# differential_evolution step 260: f(x)= 4984.115530399279
# differential_evolution step 261: f(x)= 4984.115530399279
# differential_evolution step 262: f(x)= 4984.115530399279
# differential_evolution step 263: f(x)= 4984.115530399279
# differential_evolution step 264: f(x)= 4984.115530399279
# differential_evolution step 265: f(x)= 4984.115530399279
# differential_evolution step 266: f(x)= 4984.115530399279
# differential_evolution step 267: f(x)= 4977.073892776338
# differential_evolution step 268: f(x)= 4977.073892776338
# differential_evolution step 269: f(x)= 4977.073892776338
# differential_evolution step 270: f(x)= 4977.073892776338
# differential_evolution step 271: f(x)= 4977.073892776338
# differential_evolution step 272: f(x)= 4958.563636521256
# differential_evolution step 273: f(x)= 4958.563636521256
# differential_evolution step 274: f(x)= 4950.835413378473
# differential_evolution step 275: f(x)= 4950.835413378473
# differential_evolution step 276: f(x)= 4950.835413378473
# differential_evolution step 277: f(x)= 4950.835413378473
# differential_evolution step 278: f(x)= 4950.835413378473
# differential_evolution step 279: f(x)= 4950.835413378473
# differential_evolution step 280: f(x)= 4950.835413378473
# differential_evolution step 281: f(x)= 4943.741505064501
# differential_evolution step 282: f(x)= 4943.741505064501
# differential_evolution step 283: f(x)= 4943.741505064501
# differential_evolution step 284: f(x)= 4943.741505064501
# differential_evolution step 285: f(x)= 4943.741505064501
# differential_evolution step 286: f(x)= 4943.741505064501
# differential_evolution step 287: f(x)= 4943.741505064501
# differential_evolution step 288: f(x)= 4943.741505064501
# differential_evolution step 289: f(x)= 4943.741505064501
# differential_evolution step 290: f(x)= 4928.67693007398
# differential_evolution step 291: f(x)= 4928.67693007398
# differential_evolution step 292: f(x)= 4928.67693007398
# differential_evolution step 293: f(x)= 4928.67693007398
# differential_evolution step 294: f(x)= 4928.67693007398
# differential_evolution step 295: f(x)= 4928.67693007398
# differential_evolution step 296: f(x)= 4928.67693007398
# differential_evolution step 297: f(x)= 4928.67693007398
# differential_evolution step 298: f(x)= 4916.841243272742
# differential_evolution step 299: f(x)= 4916.841243272742
# differential_evolution step 300: f(x)= 4916.841243272742
# differential_evolution step 301: f(x)= 4916.841243272742
# differential_evolution step 302: f(x)= 4916.841243272742
# differential_evolution step 303: f(x)= 4916.841243272742
# differential_evolution step 304: f(x)= 4916.841243272742
# differential_evolution step 305: f(x)= 4916.841243272742
# differential_evolution step 306: f(x)= 4916.841243272742
# differential_evolution step 307: f(x)= 4916.841243272742
# differential_evolution step 308: f(x)= 4916.841243272742
# differential_evolution step 309: f(x)= 4916.841243272742
# differential_evolution step 310: f(x)= 4910.611865490379
# differential_evolution step 311: f(x)= 4910.611865490379
# differential_evolution step 312: f(x)= 4897.226430961937
# differential_evolution step 313: f(x)= 4897.226430961937
# differential_evolution step 314: f(x)= 4897.226430961937
# differential_evolution step 315: f(x)= 4897.226430961937
# differential_evolution step 316: f(x)= 4897.226430961937
# differential_evolution step 317: f(x)= 4897.226430961937
# differential_evolution step 318: f(x)= 4897.226430961937
# differential_evolution step 319: f(x)= 4897.226430961937
# differential_evolution step 320: f(x)= 4897.226430961937
# differential_evolution step 321: f(x)= 4897.226430961937
# differential_evolution step 322: f(x)= 4897.226430961937
# differential_evolution step 323: f(x)= 4897.226430961937
# differential_evolution step 324: f(x)= 4897.226430961937
# differential_evolution step 325: f(x)= 4897.226430961937
# differential_evolution step 326: f(x)= 4897.226430961937
# differential_evolution step 327: f(x)= 4897.226430961937
# differential_evolution step 328: f(x)= 4895.558093534402
# differential_evolution step 329: f(x)= 4893.810082480994
# differential_evolution step 330: f(x)= 4893.810082480994
# differential_evolution step 331: f(x)= 4890.403846262701
# differential_evolution step 332: f(x)= 4890.403846262701
# differential_evolution step 333: f(x)= 4890.403846262701
# differential_evolution step 334: f(x)= 4890.403846262701
# differential_evolution step 335: f(x)= 4890.403846262701
# differential_evolution step 336: f(x)= 4890.403846262701
# differential_evolution step 337: f(x)= 4882.8866841787885
# differential_evolution step 338: f(x)= 4882.8866841787885
# differential_evolution step 339: f(x)= 4882.8866841787885
# differential_evolution step 340: f(x)= 4882.8866841787885
# differential_evolution step 341: f(x)= 4882.8866841787885
# differential_evolution step 342: f(x)= 4882.8866841787885
# differential_evolution step 343: f(x)= 4879.6147417951925
# differential_evolution step 344: f(x)= 4879.6147417951925
# differential_evolution step 345: f(x)= 4879.6147417951925
# differential_evolution step 346: f(x)= 4879.30497882666
# differential_evolution step 347: f(x)= 4879.30497882666
# differential_evolution step 348: f(x)= 4879.30497882666
# differential_evolution step 349: f(x)= 4879.30497882666
# differential_evolution step 350: f(x)= 4879.30497882666
# differential_evolution step 351: f(x)= 4879.30497882666
# differential_evolution step 352: f(x)= 4879.30497882666
# differential_evolution step 353: f(x)= 4873.366347973898
# differential_evolution step 354: f(x)= 4873.366347973898
# differential_evolution step 355: f(x)= 4873.366347973898
# differential_evolution step 356: f(x)= 4873.366347973898
# differential_evolution step 357: f(x)= 4873.366347973898
# differential_evolution step 358: f(x)= 4873.366347973898
# differential_evolution step 359: f(x)= 4873.366347973898
# differential_evolution step 360: f(x)= 4873.366347973898
# differential_evolution step 361: f(x)= 4873.366347973898
# differential_evolution step 362: f(x)= 4873.366347973898
# differential_evolution step 363: f(x)= 4873.366347973898
# differential_evolution step 364: f(x)= 4873.366347973898
# differential_evolution step 365: f(x)= 4873.366347973898
# differential_evolution step 366: f(x)= 4873.366347973898
# differential_evolution step 367: f(x)= 4873.366347973898
# differential_evolution step 368: f(x)= 4873.366347973898
# differential_evolution step 369: f(x)= 4873.366347973898
# differential_evolution step 370: f(x)= 4873.366347973898
# differential_evolution step 371: f(x)= 4873.366347973898
# differential_evolution step 372: f(x)= 4873.366347973898
# differential_evolution step 373: f(x)= 4873.366347973898
# differential_evolution step 374: f(x)= 4873.366347973898
# differential_evolution step 375: f(x)= 4873.366347973898
# differential_evolution step 376: f(x)= 4873.366347973898
# differential_evolution step 377: f(x)= 4873.366347973898
# differential_evolution step 378: f(x)= 4873.366347973898
# differential_evolution step 379: f(x)= 4873.366347973898
# differential_evolution step 380: f(x)= 4873.366347973898
# differential_evolution step 381: f(x)= 4873.324786420407
# differential_evolution step 382: f(x)= 4873.324786420407
# differential_evolution step 383: f(x)= 4873.324786420407
# differential_evolution step 384: f(x)= 4873.324786420407
# differential_evolution step 385: f(x)= 4873.324786420407
# differential_evolution step 386: f(x)= 4870.1158904158
# differential_evolution step 387: f(x)= 4870.1158904158
# differential_evolution step 388: f(x)= 4870.1158904158
# differential_evolution step 389: f(x)= 4870.1158904158
# differential_evolution step 390: f(x)= 4870.1158904158
# differential_evolution step 391: f(x)= 4868.334974541349
# differential_evolution step 392: f(x)= 4868.334974541349
# differential_evolution step 393: f(x)= 4868.334974541349
# differential_evolution step 394: f(x)= 4868.334974541349
# differential_evolution step 395: f(x)= 4868.334974541349
# differential_evolution step 396: f(x)= 4868.334974541349
# differential_evolution step 397: f(x)= 4868.334974541349
# differential_evolution step 398: f(x)= 4868.334974541349
# differential_evolution step 399: f(x)= 4868.151670484164
# differential_evolution step 400: f(x)= 4867.627838725396
# differential_evolution step 401: f(x)= 4867.627838725396
# differential_evolution step 402: f(x)= 4867.627838725396
# differential_evolution step 403: f(x)= 4867.627838725396
# differential_evolution step 404: f(x)= 4867.103577649772
# differential_evolution step 405: f(x)= 4867.103577649772
# differential_evolution step 406: f(x)= 4866.911370399385
# differential_evolution step 407: f(x)= 4866.911370399385
# differential_evolution step 408: f(x)= 4866.911370399385
# differential_evolution step 409: f(x)= 4866.880066399895
# differential_evolution step 410: f(x)= 4866.677312701909
# differential_evolution step 411: f(x)= 4866.677312701909
# differential_evolution step 412: f(x)= 4866.558532947672
# differential_evolution step 413: f(x)= 4866.341196630032
# differential_evolution step 414: f(x)= 4866.341196630032
# differential_evolution step 415: f(x)= 4866.341196630032
# differential_evolution step 416: f(x)= 4866.341196630032
# differential_evolution step 417: f(x)= 4865.902795750995
# differential_evolution step 418: f(x)= 4865.902795750995
# differential_evolution step 419: f(x)= 4865.902795750995
# differential_evolution step 420: f(x)= 4865.902795750995
# differential_evolution step 421: f(x)= 4865.902795750995
# differential_evolution step 422: f(x)= 4865.902795750995
# differential_evolution step 423: f(x)= 4865.902795750995
# differential_evolution step 424: f(x)= 4865.902795750995
# differential_evolution step 425: f(x)= 4865.902795750995
# differential_evolution step 426: f(x)= 4865.886565390833
# differential_evolution step 427: f(x)= 4865.531519848785
# differential_evolution step 428: f(x)= 4865.531519848785
# differential_evolution step 429: f(x)= 4865.531519848785
# differential_evolution step 430: f(x)= 4865.531519848785
# differential_evolution step 431: f(x)= 4865.531519848785
# differential_evolution step 432: f(x)= 4865.531519848785
# differential_evolution step 433: f(x)= 4865.531519848785
# differential_evolution step 434: f(x)= 4865.531519848785
# differential_evolution step 435: f(x)= 4865.531519848785
# differential_evolution step 436: f(x)= 4865.531519848785
# differential_evolution step 437: f(x)= 4865.531519848785
# differential_evolution step 438: f(x)= 4865.531519848785
# differential_evolution step 439: f(x)= 4865.481625892485
# differential_evolution step 440: f(x)= 4865.453545867807
# differential_evolution step 441: f(x)= 4865.453545867807
# differential_evolution step 442: f(x)= 4865.453545867807
# differential_evolution step 443: f(x)= 4865.453545867807
# differential_evolution step 444: f(x)= 4865.453545867807
# differential_evolution step 445: f(x)= 4865.453545867807
# differential_evolution step 446: f(x)= 4865.436677379926
# differential_evolution step 447: f(x)= 4865.41531189537
# differential_evolution step 448: f(x)= 4865.41531189537
# differential_evolution step 449: f(x)= 4865.375084902166
# differential_evolution step 450: f(x)= 4865.375084902166
# differential_evolution step 451: f(x)= 4865.375084902166
# differential_evolution step 452: f(x)= 4865.255353115574
# differential_evolution step 453: f(x)= 4865.255353115574
# differential_evolution step 454: f(x)= 4865.255353115574
# differential_evolution step 455: f(x)= 4865.255353115574
# differential_evolution step 456: f(x)= 4865.255353115574
# differential_evolution step 457: f(x)= 4865.255353115574
# differential_evolution step 458: f(x)= 4865.255353115574
# differential_evolution step 459: f(x)= 4865.238401677283
# differential_evolution step 460: f(x)= 4865.238401677283
# differential_evolution step 461: f(x)= 4865.204870695634
# differential_evolution step 462: f(x)= 4865.179296030853
# differential_evolution step 463: f(x)= 4865.116729249009
# differential_evolution step 464: f(x)= 4865.116729249009
# differential_evolution step 465: f(x)= 4865.116729249009
# differential_evolution step 466: f(x)= 4865.116729249009
# differential_evolution step 467: f(x)= 4865.116729249009
# differential_evolution step 468: f(x)= 4865.116729249009
# differential_evolution step 469: f(x)= 4865.116729249009
# differential_evolution step 470: f(x)= 4865.056840071254
# differential_evolution step 471: f(x)= 4865.056840071254
# differential_evolution step 472: f(x)= 4865.056840071254
# differential_evolution step 473: f(x)= 4865.056840071254
# differential_evolution step 474: f(x)= 4865.056840071254
# differential_evolution step 475: f(x)= 4865.056840071254
# differential_evolution step 476: f(x)= 4865.056840071254
# differential_evolution step 477: f(x)= 4865.056840071254
# differential_evolution step 478: f(x)= 4865.00322700865
# differential_evolution step 479: f(x)= 4865.00322700865
# differential_evolution step 480: f(x)= 4865.00322700865
# differential_evolution step 481: f(x)= 4865.00322700865
# differential_evolution step 482: f(x)= 4864.989694665411
# differential_evolution step 483: f(x)= 4864.985106479385
# differential_evolution step 484: f(x)= 4864.985106479385
# differential_evolution step 485: f(x)= 4864.985106479385
# differential_evolution step 486: f(x)= 4864.985106479385
# differential_evolution step 487: f(x)= 4864.985106479385
# differential_evolution step 488: f(x)= 4864.97005467021
# differential_evolution step 489: f(x)= 4864.97005467021
# differential_evolution step 490: f(x)= 4864.97005467021
# differential_evolution step 491: f(x)= 4864.97005467021
# differential_evolution step 492: f(x)= 4864.97005467021
# differential_evolution step 493: f(x)= 4864.97005467021
# differential_evolution step 494: f(x)= 4864.97005467021
# differential_evolution step 495: f(x)= 4864.97005467021
# differential_evolution step 496: f(x)= 4864.97005467021
# differential_evolution step 497: f(x)= 4864.97005467021
# differential_evolution step 498: f(x)= 4864.97005467021
# differential_evolution step 499: f(x)= 4864.951446767446
# differential_evolution step 500: f(x)= 4864.951446767446
# differential_evolution step 501: f(x)= 4864.951446767446
# differential_evolution step 502: f(x)= 4864.951446767446
# differential_evolution step 503: f(x)= 4864.951446767446
# differential_evolution step 504: f(x)= 4864.951446767446
# differential_evolution step 505: f(x)= 4864.920606150435
# differential_evolution step 506: f(x)= 4864.920606150435
# differential_evolution step 507: f(x)= 4864.920606150435
# differential_evolution step 508: f(x)= 4864.920606150435
# differential_evolution step 509: f(x)= 4864.920606150435
# differential_evolution step 510: f(x)= 4864.920606150435
# differential_evolution step 511: f(x)= 4864.920606150435
# differential_evolution step 512: f(x)= 4864.920606150435
# differential_evolution step 513: f(x)= 4864.920606150435
# differential_evolution step 514: f(x)= 4864.910657187779
# differential_evolution step 515: f(x)= 4864.910657187779
# differential_evolution step 516: f(x)= 4864.902676447782
# differential_evolution step 517: f(x)= 4864.902676447782
# differential_evolution step 518: f(x)= 4864.902676447782
# differential_evolution step 519: f(x)= 4864.902676447782
# differential_evolution step 520: f(x)= 4864.902676447782
# differential_evolution step 521: f(x)= 4864.902676447782
# differential_evolution step 522: f(x)= 4864.902676447782
# differential_evolution step 523: f(x)= 4864.902676447782
# differential_evolution step 524: f(x)= 4864.902676447782
# differential_evolution step 525: f(x)= 4864.902676447782
# differential_evolution step 526: f(x)= 4864.902676447782
# differential_evolution step 527: f(x)= 4864.902676447782
# differential_evolution step 528: f(x)= 4864.8964166719115
# differential_evolution step 529: f(x)= 4864.8964166719115
# differential_evolution step 530: f(x)= 4864.8964166719115
# differential_evolution step 531: f(x)= 4864.8964166719115
# differential_evolution step 532: f(x)= 4864.8964166719115
# differential_evolution step 533: f(x)= 4864.8964166719115
# differential_evolution step 534: f(x)= 4864.8964166719115
# differential_evolution step 535: f(x)= 4864.8964166719115
# differential_evolution step 536: f(x)= 4864.895395503027
# differential_evolution step 537: f(x)= 4864.895323297877
# differential_evolution step 538: f(x)= 4864.895323297877
# differential_evolution step 539: f(x)= 4864.895323297877
# differential_evolution step 540: f(x)= 4864.895323297877
# differential_evolution step 541: f(x)= 4864.895323297877
# differential_evolution step 542: f(x)= 4864.893668728485
# differential_evolution step 543: f(x)= 4864.893668728485
# differential_evolution step 544: f(x)= 4864.890762200488
# differential_evolution step 545: f(x)= 4864.890762200488
# differential_evolution step 546: f(x)= 4864.890762200488
# differential_evolution step 547: f(x)= 4864.889026706028
# differential_evolution step 548: f(x)= 4864.888802161569
# differential_evolution step 549: f(x)= 4864.888802161569
# differential_evolution step 550: f(x)= 4864.888802161569
# differential_evolution step 551: f(x)= 4864.888802161569
# differential_evolution step 552: f(x)= 4864.888802161569
# differential_evolution step 553: f(x)= 4864.886917721061
# differential_evolution step 554: f(x)= 4864.886917721061
# differential_evolution step 555: f(x)= 4864.88470980728
# differential_evolution step 556: f(x)= 4864.88470980728
# differential_evolution step 557: f(x)= 4864.88470980728
# differential_evolution step 558: f(x)= 4864.88470980728
# differential_evolution step 559: f(x)= 4864.88470980728
# differential_evolution step 560: f(x)= 4864.88470980728
# differential_evolution step 561: f(x)= 4864.88343210078
# differential_evolution step 562: f(x)= 4864.88343210078
# differential_evolution step 563: f(x)= 4864.88343210078
# differential_evolution step 564: f(x)= 4864.8828016829275
# differential_evolution step 565: f(x)= 4864.8828016829275
# differential_evolution step 566: f(x)= 4864.8828016829275
# differential_evolution step 567: f(x)= 4864.8828016829275
# differential_evolution step 568: f(x)= 4864.8828016829275
# differential_evolution step 569: f(x)= 4864.8828016829275
# differential_evolution step 570: f(x)= 4864.8828016829275
# differential_evolution step 571: f(x)= 4864.8828016829275
# differential_evolution step 572: f(x)= 4864.88159065249
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=20.0000, r_e=10.4150, n=1.5433, x_0=44.1241
# Sérsic 2: I_e=20.0000, r_e=2.8714, n=0.6559, x_0=53.0000
# Sérsic 3: I_e=20.0000, r_e=8.3014, n=1.8911, x_0=57.0000
# Chi quadro minimo: 4864.878045628581
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_error_HA, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)
    
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = radial_profile_error_continuum_1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, radial_profile_continuum_1, radial_profile_error_continuum_1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=6.8344, r_e=20.5673, n=2.3283, x_0=44.0233
# Sérsic 2: I_e=17.3337, r_e=6.0821, n=0.7814, x_0=53.0000
# Sérsic 3: I_e=19.9999, r_e=6.9318, n=1.8847, x_0=57.0000
# [ 2.5349808   4.63283912  0.26213856  0.11295244 17.42578472  3.76674888
#   0.48446423  2.37318659 15.82803458  2.48906597  0.56347493  0.15743615]
# 727.7937033726784

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 100924.87179612339
# differential_evolution step 2: f(x)= 82031.90125367833
# differential_evolution step 3: f(x)= 71471.62844793689
# differential_evolution step 4: f(x)= 34843.989706452056
# differential_evolution step 5: f(x)= 34843.989706452056
# differential_evolution step 6: f(x)= 28268.436045484763
# differential_evolution step 7: f(x)= 18453.34599715341
# differential_evolution step 8: f(x)= 18453.34599715341
# differential_evolution step 9: f(x)= 18453.34599715341
# differential_evolution step 10: f(x)= 18453.34599715341
# differential_evolution step 11: f(x)= 11995.480350088212
# differential_evolution step 12: f(x)= 11995.480350088212
# differential_evolution step 13: f(x)= 11995.480350088212
# differential_evolution step 14: f(x)= 11995.480350088212
# differential_evolution step 15: f(x)= 11995.480350088212
# differential_evolution step 16: f(x)= 11995.480350088212
# differential_evolution step 17: f(x)= 11995.480350088212
# differential_evolution step 18: f(x)= 9198.967021285664
# differential_evolution step 19: f(x)= 9198.967021285664
# differential_evolution step 20: f(x)= 9198.967021285664
# differential_evolution step 21: f(x)= 9198.967021285664
# differential_evolution step 22: f(x)= 8710.70123224423
# differential_evolution step 23: f(x)= 7205.0996066089265
# differential_evolution step 24: f(x)= 4285.165818707192
# differential_evolution step 25: f(x)= 4285.165818707192
# differential_evolution step 26: f(x)= 4285.165818707192
# differential_evolution step 27: f(x)= 4285.165818707192
# differential_evolution step 28: f(x)= 4285.165818707192
# differential_evolution step 29: f(x)= 4285.165818707192
# differential_evolution step 30: f(x)= 4285.165818707192
# differential_evolution step 31: f(x)= 4285.165818707192
# differential_evolution step 32: f(x)= 4285.165818707192
# differential_evolution step 33: f(x)= 4285.165818707192
# differential_evolution step 34: f(x)= 4285.165818707192
# differential_evolution step 35: f(x)= 4285.165818707192
# differential_evolution step 36: f(x)= 4285.165818707192
# differential_evolution step 37: f(x)= 4285.165818707192
# differential_evolution step 38: f(x)= 4285.165818707192
# differential_evolution step 39: f(x)= 4285.165818707192
# differential_evolution step 40: f(x)= 4285.165818707192
# differential_evolution step 41: f(x)= 4285.165818707192
# differential_evolution step 42: f(x)= 4285.165818707192
# differential_evolution step 43: f(x)= 4285.165818707192
# differential_evolution step 44: f(x)= 4285.165818707192
# differential_evolution step 45: f(x)= 4285.165818707192
# differential_evolution step 46: f(x)= 4170.000459166806
# differential_evolution step 47: f(x)= 3779.044034544704
# differential_evolution step 48: f(x)= 3779.044034544704
# differential_evolution step 49: f(x)= 3779.044034544704
# differential_evolution step 50: f(x)= 3707.407231193548
# differential_evolution step 51: f(x)= 3707.407231193548
# differential_evolution step 52: f(x)= 3707.407231193548
# differential_evolution step 53: f(x)= 3243.2249164070136
# differential_evolution step 54: f(x)= 3243.2249164070136
# differential_evolution step 55: f(x)= 3243.2249164070136
# differential_evolution step 56: f(x)= 3243.2249164070136
# differential_evolution step 57: f(x)= 3243.2249164070136
# differential_evolution step 58: f(x)= 3243.2249164070136
# differential_evolution step 59: f(x)= 3243.2249164070136
# differential_evolution step 60: f(x)= 3243.2249164070136
# differential_evolution step 61: f(x)= 3243.2249164070136
# differential_evolution step 62: f(x)= 3243.2249164070136
# differential_evolution step 63: f(x)= 3219.2417732736744
# differential_evolution step 64: f(x)= 3219.2417732736744
# differential_evolution step 65: f(x)= 3219.2417732736744
# differential_evolution step 66: f(x)= 3219.2417732736744
# differential_evolution step 67: f(x)= 3219.2417732736744
# differential_evolution step 68: f(x)= 3219.2417732736744
# differential_evolution step 69: f(x)= 3219.2417732736744
# differential_evolution step 70: f(x)= 3188.8855177293017
# differential_evolution step 71: f(x)= 3188.8855177293017
# differential_evolution step 72: f(x)= 3071.9068722742663
# differential_evolution step 73: f(x)= 3071.9068722742663
# differential_evolution step 74: f(x)= 3071.9068722742663
# differential_evolution step 75: f(x)= 3071.9068722742663
# differential_evolution step 76: f(x)= 3027.2264371016536
# differential_evolution step 77: f(x)= 3027.2264371016536
# differential_evolution step 78: f(x)= 3027.2264371016536
# differential_evolution step 79: f(x)= 3027.2264371016536
# differential_evolution step 80: f(x)= 3027.2264371016536
# differential_evolution step 81: f(x)= 3027.2264371016536
# differential_evolution step 82: f(x)= 2925.0215401467085
# differential_evolution step 83: f(x)= 2843.4696257624264
# differential_evolution step 84: f(x)= 2843.4696257624264
# differential_evolution step 85: f(x)= 2843.4696257624264
# differential_evolution step 86: f(x)= 2795.4735875413035
# differential_evolution step 87: f(x)= 2795.4735875413035
# differential_evolution step 88: f(x)= 2631.0273477380783
# differential_evolution step 89: f(x)= 2631.0273477380783
# differential_evolution step 90: f(x)= 2631.0273477380783
# differential_evolution step 91: f(x)= 2631.0273477380783
# differential_evolution step 92: f(x)= 2631.0273477380783
# differential_evolution step 93: f(x)= 2631.0273477380783
# differential_evolution step 94: f(x)= 2631.0273477380783
# differential_evolution step 95: f(x)= 2631.0273477380783
# differential_evolution step 96: f(x)= 2624.903644980706
# differential_evolution step 97: f(x)= 2624.903644980706
# differential_evolution step 98: f(x)= 2624.903644980706
# differential_evolution step 99: f(x)= 2624.903644980706
# differential_evolution step 100: f(x)= 2624.903644980706
# differential_evolution step 101: f(x)= 2624.903644980706
# differential_evolution step 102: f(x)= 2624.903644980706
# differential_evolution step 103: f(x)= 2624.903644980706
# differential_evolution step 104: f(x)= 2600.6758379753296
# differential_evolution step 105: f(x)= 2505.5103374396963
# differential_evolution step 106: f(x)= 2505.5103374396963
# differential_evolution step 107: f(x)= 2505.5103374396963
# differential_evolution step 108: f(x)= 2505.5103374396963
# differential_evolution step 109: f(x)= 2505.5103374396963
# differential_evolution step 110: f(x)= 2482.320809617447
# differential_evolution step 111: f(x)= 2482.320809617447
# differential_evolution step 112: f(x)= 2482.320809617447
# differential_evolution step 113: f(x)= 2482.320809617447
# differential_evolution step 114: f(x)= 2482.320809617447
# differential_evolution step 115: f(x)= 2482.320809617447
# differential_evolution step 116: f(x)= 2482.320809617447
# differential_evolution step 117: f(x)= 2417.8769332420466
# differential_evolution step 118: f(x)= 2417.8769332420466
# differential_evolution step 119: f(x)= 2417.8769332420466
# differential_evolution step 120: f(x)= 2417.8769332420466
# differential_evolution step 121: f(x)= 2349.3107708613097
# differential_evolution step 122: f(x)= 2349.3107708613097
# differential_evolution step 123: f(x)= 2349.3107708613097
# differential_evolution step 124: f(x)= 2349.3107708613097
# differential_evolution step 125: f(x)= 2349.3107708613097
# differential_evolution step 126: f(x)= 2349.3107708613097
# differential_evolution step 127: f(x)= 2349.3107708613097
# differential_evolution step 128: f(x)= 2349.3107708613097
# differential_evolution step 129: f(x)= 2349.3107708613097
# differential_evolution step 130: f(x)= 2349.3107708613097
# differential_evolution step 131: f(x)= 2333.9918625303953
# differential_evolution step 132: f(x)= 2333.9918625303953
# differential_evolution step 133: f(x)= 2333.9918625303953
# differential_evolution step 134: f(x)= 2333.9918625303953
# differential_evolution step 135: f(x)= 2333.9918625303953
# differential_evolution step 136: f(x)= 2333.9918625303953
# differential_evolution step 137: f(x)= 2333.9918625303953
# differential_evolution step 138: f(x)= 2333.9918625303953
# differential_evolution step 139: f(x)= 2333.9918625303953
# differential_evolution step 140: f(x)= 2333.9918625303953
# differential_evolution step 141: f(x)= 2333.9918625303953
# differential_evolution step 142: f(x)= 2325.5172939690606
# differential_evolution step 143: f(x)= 2325.5172939690606
# differential_evolution step 144: f(x)= 2325.5172939690606
# differential_evolution step 145: f(x)= 2325.5172939690606
# differential_evolution step 146: f(x)= 2325.5172939690606
# differential_evolution step 147: f(x)= 2325.5172939690606
# differential_evolution step 148: f(x)= 2290.318937822942
# differential_evolution step 149: f(x)= 2286.974891924934
# differential_evolution step 150: f(x)= 2286.974891924934
# differential_evolution step 151: f(x)= 2236.7181369023724
# differential_evolution step 152: f(x)= 2236.7181369023724
# differential_evolution step 153: f(x)= 2236.7181369023724
# differential_evolution step 154: f(x)= 2236.7181369023724
# differential_evolution step 155: f(x)= 2236.7181369023724
# differential_evolution step 156: f(x)= 2236.7181369023724
# differential_evolution step 157: f(x)= 2236.7181369023724
# differential_evolution step 158: f(x)= 2236.7181369023724
# differential_evolution step 159: f(x)= 2236.7181369023724
# differential_evolution step 160: f(x)= 2236.7181369023724
# differential_evolution step 161: f(x)= 2218.2307467426667
# differential_evolution step 162: f(x)= 2218.2307467426667
# differential_evolution step 163: f(x)= 2218.2307467426667
# differential_evolution step 164: f(x)= 2218.2307467426667
# differential_evolution step 165: f(x)= 2218.2307467426667
# differential_evolution step 166: f(x)= 2218.2307467426667
# differential_evolution step 167: f(x)= 2183.049006381547
# differential_evolution step 168: f(x)= 2183.049006381547
# differential_evolution step 169: f(x)= 2183.049006381547
# differential_evolution step 170: f(x)= 2112.0548699525575
# differential_evolution step 171: f(x)= 2112.0548699525575
# differential_evolution step 172: f(x)= 2112.0548699525575
# differential_evolution step 173: f(x)= 2112.0548699525575
# differential_evolution step 174: f(x)= 2112.0548699525575
# differential_evolution step 175: f(x)= 2112.0548699525575
# differential_evolution step 176: f(x)= 2112.0548699525575
# differential_evolution step 177: f(x)= 2112.0548699525575
# differential_evolution step 178: f(x)= 2112.0548699525575
# differential_evolution step 179: f(x)= 2112.0548699525575
# differential_evolution step 180: f(x)= 2112.0548699525575
# differential_evolution step 181: f(x)= 2112.0548699525575
# differential_evolution step 182: f(x)= 2112.0548699525575
# differential_evolution step 183: f(x)= 2112.0548699525575
# differential_evolution step 184: f(x)= 2112.0548699525575
# differential_evolution step 185: f(x)= 2112.0548699525575
# differential_evolution step 186: f(x)= 2112.0548699525575
# differential_evolution step 187: f(x)= 2112.0548699525575
# differential_evolution step 188: f(x)= 2091.142903273961
# differential_evolution step 189: f(x)= 2091.142903273961
# differential_evolution step 190: f(x)= 2091.142903273961
# differential_evolution step 191: f(x)= 2091.142903273961
# differential_evolution step 192: f(x)= 2091.142903273961
# differential_evolution step 193: f(x)= 2091.142903273961
# differential_evolution step 194: f(x)= 2091.142903273961
# differential_evolution step 195: f(x)= 2091.142903273961
# differential_evolution step 196: f(x)= 2091.142903273961
# differential_evolution step 197: f(x)= 2083.8938459577644
# differential_evolution step 198: f(x)= 2083.8938459577644
# differential_evolution step 199: f(x)= 2083.8938459577644
# differential_evolution step 200: f(x)= 2083.8938459577644
# differential_evolution step 201: f(x)= 2083.8938459577644
# differential_evolution step 202: f(x)= 2083.8938459577644
# differential_evolution step 203: f(x)= 2083.8938459577644
# differential_evolution step 204: f(x)= 2083.8938459577644
# differential_evolution step 205: f(x)= 2069.2945480190574
# differential_evolution step 206: f(x)= 2069.2945480190574
# differential_evolution step 207: f(x)= 2044.657684572885
# differential_evolution step 208: f(x)= 2044.657684572885
# differential_evolution step 209: f(x)= 2044.657684572885
# differential_evolution step 210: f(x)= 2044.657684572885
# differential_evolution step 211: f(x)= 2044.657684572885
# differential_evolution step 212: f(x)= 2044.657684572885
# differential_evolution step 213: f(x)= 2044.657684572885
# differential_evolution step 214: f(x)= 2044.657684572885
# differential_evolution step 215: f(x)= 2044.657684572885
# differential_evolution step 216: f(x)= 2044.657684572885
# differential_evolution step 217: f(x)= 2044.657684572885
# differential_evolution step 218: f(x)= 2044.657684572885
# differential_evolution step 219: f(x)= 2044.657684572885
# differential_evolution step 220: f(x)= 2044.657684572885
# differential_evolution step 221: f(x)= 2044.657684572885
# differential_evolution step 222: f(x)= 2044.657684572885
# differential_evolution step 223: f(x)= 2018.4720441128877
# differential_evolution step 224: f(x)= 2018.4720441128877
# differential_evolution step 225: f(x)= 2018.4720441128877
# differential_evolution step 226: f(x)= 2018.4720441128877
# differential_evolution step 227: f(x)= 2018.4720441128877
# differential_evolution step 228: f(x)= 2018.4720441128877
# differential_evolution step 229: f(x)= 2018.4720441128877
# differential_evolution step 230: f(x)= 2018.4720441128877
# differential_evolution step 231: f(x)= 2018.4720441128877
# differential_evolution step 232: f(x)= 2018.4720441128877
# differential_evolution step 233: f(x)= 2018.4720441128877
# differential_evolution step 234: f(x)= 2018.4720441128877
# differential_evolution step 235: f(x)= 2018.4720441128877
# differential_evolution step 236: f(x)= 2018.4720441128877
# differential_evolution step 237: f(x)= 2018.4720441128877
# differential_evolution step 238: f(x)= 2018.4720441128877
# differential_evolution step 239: f(x)= 2018.4720441128877
# differential_evolution step 240: f(x)= 2013.4541291997887
# differential_evolution step 241: f(x)= 2013.4541291997887
# differential_evolution step 242: f(x)= 2013.4541291997887
# differential_evolution step 243: f(x)= 2013.4541291997887
# differential_evolution step 244: f(x)= 2013.4541291997887
# differential_evolution step 245: f(x)= 2013.4541291997887
# differential_evolution step 246: f(x)= 2013.4541291997887
# differential_evolution step 247: f(x)= 2013.4541291997887
# differential_evolution step 248: f(x)= 2013.4541291997887
# differential_evolution step 249: f(x)= 2013.4541291997887
# differential_evolution step 250: f(x)= 2013.4541291997887
# differential_evolution step 251: f(x)= 2008.4442654978043
# differential_evolution step 252: f(x)= 2008.4442654978043
# differential_evolution step 253: f(x)= 2008.4442654978043
# differential_evolution step 254: f(x)= 2008.4442654978043
# differential_evolution step 255: f(x)= 2008.4442654978043
# differential_evolution step 256: f(x)= 2000.9978496795075
# differential_evolution step 257: f(x)= 2000.9978496795075
# differential_evolution step 258: f(x)= 2000.9978496795075
# differential_evolution step 259: f(x)= 2000.9978496795075
# differential_evolution step 260: f(x)= 2000.9978496795075
# differential_evolution step 261: f(x)= 2000.9978496795075
# differential_evolution step 262: f(x)= 2000.9978496795075
# differential_evolution step 263: f(x)= 1998.7241845584208
# differential_evolution step 264: f(x)= 1998.7241845584208
# differential_evolution step 265: f(x)= 1998.7241845584208
# differential_evolution step 266: f(x)= 1998.7241845584208
# differential_evolution step 267: f(x)= 1998.7241845584208
# differential_evolution step 268: f(x)= 1995.888699460206
# differential_evolution step 269: f(x)= 1995.888699460206
# differential_evolution step 270: f(x)= 1995.888699460206
# differential_evolution step 271: f(x)= 1991.0898304183465
# differential_evolution step 272: f(x)= 1991.0898304183465
# differential_evolution step 273: f(x)= 1991.0898304183465
# differential_evolution step 274: f(x)= 1991.0898304183465
# differential_evolution step 275: f(x)= 1991.0898304183465
# differential_evolution step 276: f(x)= 1982.974926950256
# differential_evolution step 277: f(x)= 1982.974926950256
# differential_evolution step 278: f(x)= 1982.974926950256
# differential_evolution step 279: f(x)= 1982.974926950256
# differential_evolution step 280: f(x)= 1982.974926950256
# differential_evolution step 281: f(x)= 1982.974926950256
# differential_evolution step 282: f(x)= 1982.974926950256
# differential_evolution step 283: f(x)= 1982.974926950256
# differential_evolution step 284: f(x)= 1982.974926950256
# differential_evolution step 285: f(x)= 1982.974926950256
# differential_evolution step 286: f(x)= 1982.974926950256
# differential_evolution step 287: f(x)= 1982.974926950256
# differential_evolution step 288: f(x)= 1977.7748680792765
# differential_evolution step 289: f(x)= 1977.7748680792765
# differential_evolution step 290: f(x)= 1977.7748680792765
# differential_evolution step 291: f(x)= 1977.7748680792765
# differential_evolution step 292: f(x)= 1977.7748680792765
# differential_evolution step 293: f(x)= 1977.7748680792765
# differential_evolution step 294: f(x)= 1977.7748680792765
# differential_evolution step 295: f(x)= 1977.7748680792765
# differential_evolution step 296: f(x)= 1977.7748680792765
# differential_evolution step 297: f(x)= 1977.7748680792765
# differential_evolution step 298: f(x)= 1977.7748680792765
# differential_evolution step 299: f(x)= 1977.7748680792765
# differential_evolution step 300: f(x)= 1977.7748680792765
# differential_evolution step 301: f(x)= 1977.7748680792765
# differential_evolution step 302: f(x)= 1977.7748680792765
# differential_evolution step 303: f(x)= 1977.7748680792765
# differential_evolution step 304: f(x)= 1977.7748680792765
# differential_evolution step 305: f(x)= 1977.7748680792765
# differential_evolution step 306: f(x)= 1977.7748680792765
# differential_evolution step 307: f(x)= 1977.7748680792765
# differential_evolution step 308: f(x)= 1977.7748680792765
# differential_evolution step 309: f(x)= 1977.7748680792765
# differential_evolution step 310: f(x)= 1977.7748680792765
# differential_evolution step 311: f(x)= 1977.7748680792765
# differential_evolution step 312: f(x)= 1977.7748680792765
# differential_evolution step 313: f(x)= 1977.7748680792765
# differential_evolution step 314: f(x)= 1977.7748680792765
# differential_evolution step 315: f(x)= 1977.7748680792765
# differential_evolution step 316: f(x)= 1977.7748680792765
# differential_evolution step 317: f(x)= 1977.7748680792765
# differential_evolution step 318: f(x)= 1977.7748680792765
# differential_evolution step 319: f(x)= 1977.7748680792765
# differential_evolution step 320: f(x)= 1977.7748680792765
# differential_evolution step 321: f(x)= 1977.7748680792765
# differential_evolution step 322: f(x)= 1977.7748680792765
# differential_evolution step 323: f(x)= 1977.7748680792765
# differential_evolution step 324: f(x)= 1977.7748680792765
# differential_evolution step 325: f(x)= 1977.7748680792765
# differential_evolution step 326: f(x)= 1977.7748680792765
# differential_evolution step 327: f(x)= 1977.7748680792765
# differential_evolution step 328: f(x)= 1977.7748680792765
# differential_evolution step 329: f(x)= 1977.7748680792765
# differential_evolution step 330: f(x)= 1975.6835823852425
# differential_evolution step 331: f(x)= 1971.0700425285886
# differential_evolution step 332: f(x)= 1971.0700425285886
# differential_evolution step 333: f(x)= 1971.0700425285886
# differential_evolution step 334: f(x)= 1971.0700425285886
# differential_evolution step 335: f(x)= 1968.3025820902333
# differential_evolution step 336: f(x)= 1968.3025820902333
# differential_evolution step 337: f(x)= 1968.3025820902333
# differential_evolution step 338: f(x)= 1968.3025820902333
# differential_evolution step 339: f(x)= 1968.3025820902333
# differential_evolution step 340: f(x)= 1968.3025820902333
# differential_evolution step 341: f(x)= 1968.3025820902333
# differential_evolution step 342: f(x)= 1968.3025820902333
# differential_evolution step 343: f(x)= 1968.3025820902333
# differential_evolution step 344: f(x)= 1968.3025820902333
# differential_evolution step 345: f(x)= 1968.3025820902333
# differential_evolution step 346: f(x)= 1968.3025820902333
# differential_evolution step 347: f(x)= 1968.3025820902333
# differential_evolution step 348: f(x)= 1968.3025820902333
# differential_evolution step 349: f(x)= 1968.3025820902333
# differential_evolution step 350: f(x)= 1968.3025820902333
# differential_evolution step 351: f(x)= 1968.3025820902333
# differential_evolution step 352: f(x)= 1968.3025820902333
# differential_evolution step 353: f(x)= 1968.3025820902333
# differential_evolution step 354: f(x)= 1968.3025820902333
# differential_evolution step 355: f(x)= 1968.3025820902333
# differential_evolution step 356: f(x)= 1968.115485993084
# differential_evolution step 357: f(x)= 1968.115485993084
# differential_evolution step 358: f(x)= 1968.115485993084
# differential_evolution step 359: f(x)= 1968.115485993084
# differential_evolution step 360: f(x)= 1968.115485993084
# differential_evolution step 361: f(x)= 1968.115485993084
# differential_evolution step 362: f(x)= 1968.115485993084
# differential_evolution step 363: f(x)= 1968.115485993084
# differential_evolution step 364: f(x)= 1968.115485993084
# differential_evolution step 365: f(x)= 1968.115485993084
# differential_evolution step 366: f(x)= 1968.115485993084
# differential_evolution step 367: f(x)= 1967.4764197513184
# differential_evolution step 368: f(x)= 1967.4764197513184
# differential_evolution step 369: f(x)= 1967.4764197513184
# differential_evolution step 370: f(x)= 1967.4764197513184
# differential_evolution step 371: f(x)= 1967.4764197513184
# differential_evolution step 372: f(x)= 1967.4764197513184
# differential_evolution step 373: f(x)= 1967.4764197513184
# differential_evolution step 374: f(x)= 1967.4764197513184
# differential_evolution step 375: f(x)= 1967.4764197513184
# differential_evolution step 376: f(x)= 1967.4764197513184
# differential_evolution step 377: f(x)= 1967.020679817785
# differential_evolution step 378: f(x)= 1967.020679817785
# differential_evolution step 379: f(x)= 1967.020679817785
# differential_evolution step 380: f(x)= 1967.020679817785
# differential_evolution step 381: f(x)= 1967.020679817785
# differential_evolution step 382: f(x)= 1967.020679817785
# differential_evolution step 383: f(x)= 1967.020679817785
# differential_evolution step 384: f(x)= 1967.020679817785
# differential_evolution step 385: f(x)= 1967.020679817785
# differential_evolution step 386: f(x)= 1967.020679817785
# differential_evolution step 387: f(x)= 1967.020679817785
# differential_evolution step 388: f(x)= 1967.020679817785
# differential_evolution step 389: f(x)= 1967.020679817785
# differential_evolution step 390: f(x)= 1967.020679817785
# differential_evolution step 391: f(x)= 1967.020679817785
# differential_evolution step 392: f(x)= 1966.9858313796256
# differential_evolution step 393: f(x)= 1966.9858313796256
# differential_evolution step 394: f(x)= 1966.9858313796256
# differential_evolution step 395: f(x)= 1966.9858313796256
# differential_evolution step 396: f(x)= 1966.9858313796256
# differential_evolution step 397: f(x)= 1966.9858313796256
# differential_evolution step 398: f(x)= 1966.9858313796256
# differential_evolution step 399: f(x)= 1966.9858313796256
# differential_evolution step 400: f(x)= 1966.9858313796256
# differential_evolution step 401: f(x)= 1966.9858313796256
# differential_evolution step 402: f(x)= 1966.9858313796256
# differential_evolution step 403: f(x)= 1966.9858313796256
# differential_evolution step 404: f(x)= 1966.9538280250647
# differential_evolution step 405: f(x)= 1966.9538280250647
# differential_evolution step 406: f(x)= 1966.9538280250647
# differential_evolution step 407: f(x)= 1966.9538280250647
# differential_evolution step 408: f(x)= 1966.9538280250647
# differential_evolution step 409: f(x)= 1966.9538280250647
# differential_evolution step 410: f(x)= 1966.9538280250647
# differential_evolution step 411: f(x)= 1966.9538280250647
# differential_evolution step 412: f(x)= 1966.9538280250647
# differential_evolution step 413: f(x)= 1966.9538280250647
# differential_evolution step 414: f(x)= 1966.9538280250647
# differential_evolution step 415: f(x)= 1966.9538280250647
# differential_evolution step 416: f(x)= 1966.9538280250647
# differential_evolution step 417: f(x)= 1966.9538280250647
# differential_evolution step 418: f(x)= 1966.799990413006
# differential_evolution step 419: f(x)= 1966.6828113081592
# differential_evolution step 420: f(x)= 1965.5883910245475
# differential_evolution step 421: f(x)= 1965.5883910245475
# differential_evolution step 422: f(x)= 1965.5883910245475
# differential_evolution step 423: f(x)= 1964.6458360618158
# differential_evolution step 424: f(x)= 1964.6458360618158
# differential_evolution step 425: f(x)= 1964.6458360618158
# differential_evolution step 426: f(x)= 1964.6458360618158
# differential_evolution step 427: f(x)= 1964.6458360618158
# differential_evolution step 428: f(x)= 1964.6458360618158
# differential_evolution step 429: f(x)= 1964.6458360618158
# differential_evolution step 430: f(x)= 1964.6458360618158
# differential_evolution step 431: f(x)= 1964.6458360618158
# differential_evolution step 432: f(x)= 1964.6458360618158
# differential_evolution step 433: f(x)= 1964.621199864241
# differential_evolution step 434: f(x)= 1964.621199864241
# differential_evolution step 435: f(x)= 1964.621199864241
# differential_evolution step 436: f(x)= 1964.621199864241
# differential_evolution step 437: f(x)= 1964.621199864241
# differential_evolution step 438: f(x)= 1964.621199864241
# differential_evolution step 439: f(x)= 1964.621199864241
# differential_evolution step 440: f(x)= 1964.621199864241
# differential_evolution step 441: f(x)= 1964.621199864241
# differential_evolution step 442: f(x)= 1964.621199864241
# differential_evolution step 443: f(x)= 1964.621199864241
# differential_evolution step 444: f(x)= 1964.621199864241
# differential_evolution step 445: f(x)= 1964.621199864241
# differential_evolution step 446: f(x)= 1964.621199864241
# differential_evolution step 447: f(x)= 1964.561168818275
# differential_evolution step 448: f(x)= 1964.561168818275
# differential_evolution step 449: f(x)= 1964.3111641561554
# differential_evolution step 450: f(x)= 1964.3111641561554
# differential_evolution step 451: f(x)= 1964.3111641561554
# differential_evolution step 452: f(x)= 1964.3111641561554
# differential_evolution step 453: f(x)= 1964.3111641561554
# differential_evolution step 454: f(x)= 1964.3111641561554
# differential_evolution step 455: f(x)= 1964.3111641561554
# differential_evolution step 456: f(x)= 1964.3111641561554
# differential_evolution step 457: f(x)= 1964.3111641561554
# differential_evolution step 458: f(x)= 1964.3111641561554
# differential_evolution step 459: f(x)= 1964.3111641561554
# differential_evolution step 460: f(x)= 1964.3111641561554
# differential_evolution step 461: f(x)= 1964.3111641561554
# differential_evolution step 462: f(x)= 1964.2138108291215
# differential_evolution step 463: f(x)= 1964.2138108291215
# differential_evolution step 464: f(x)= 1964.2138108291215
# differential_evolution step 465: f(x)= 1964.2138108291215
# differential_evolution step 466: f(x)= 1964.2138108291215
# differential_evolution step 467: f(x)= 1964.1962333432757
# differential_evolution step 468: f(x)= 1964.1962333432757
# differential_evolution step 469: f(x)= 1964.1962333432757
# differential_evolution step 470: f(x)= 1964.1962333432757
# differential_evolution step 471: f(x)= 1964.1962333432757
# differential_evolution step 472: f(x)= 1964.1962333432757
# differential_evolution step 473: f(x)= 1964.1962333432757
# differential_evolution step 474: f(x)= 1964.1962333432757
# differential_evolution step 475: f(x)= 1964.1962333432757
# differential_evolution step 476: f(x)= 1964.1962333432757
# differential_evolution step 477: f(x)= 1964.1962333432757
# differential_evolution step 478: f(x)= 1964.1962333432757
# differential_evolution step 479: f(x)= 1964.1962333432757
# differential_evolution step 480: f(x)= 1964.1962333432757
# differential_evolution step 481: f(x)= 1964.1962333432757
# differential_evolution step 482: f(x)= 1964.1962333432757
# differential_evolution step 483: f(x)= 1964.1962333432757
# differential_evolution step 484: f(x)= 1964.1962333432757
# differential_evolution step 485: f(x)= 1964.1962333432757
# differential_evolution step 486: f(x)= 1964.0018542857217
# differential_evolution step 487: f(x)= 1963.9764093033034
# differential_evolution step 488: f(x)= 1963.9764093033034
# differential_evolution step 489: f(x)= 1963.9764093033034
# differential_evolution step 490: f(x)= 1963.9764093033034
# differential_evolution step 491: f(x)= 1963.9764093033034
# differential_evolution step 492: f(x)= 1963.9764093033034
# differential_evolution step 493: f(x)= 1963.9764093033034
# differential_evolution step 494: f(x)= 1963.9764093033034
# differential_evolution step 495: f(x)= 1963.9764093033034
# differential_evolution step 496: f(x)= 1963.9764093033034
# differential_evolution step 497: f(x)= 1963.9764093033034
# differential_evolution step 498: f(x)= 1963.9764093033034
# differential_evolution step 499: f(x)= 1963.9764093033034
# differential_evolution step 500: f(x)= 1963.9764093033034
# differential_evolution step 501: f(x)= 1963.9764093033034
# differential_evolution step 502: f(x)= 1963.9764093033034
# differential_evolution step 503: f(x)= 1963.9764093033034
# differential_evolution step 504: f(x)= 1963.9764093033034
# differential_evolution step 505: f(x)= 1963.9764093033034
# differential_evolution step 506: f(x)= 1963.9764093033034
# differential_evolution step 507: f(x)= 1963.9496155471854
# differential_evolution step 508: f(x)= 1963.9496155471854
# differential_evolution step 509: f(x)= 1963.9163453137082
# differential_evolution step 510: f(x)= 1963.856920966323
# differential_evolution step 511: f(x)= 1963.856920966323
# differential_evolution step 512: f(x)= 1963.856920966323
# differential_evolution step 513: f(x)= 1963.856920966323
# differential_evolution step 514: f(x)= 1963.856920966323
# differential_evolution step 515: f(x)= 1963.7284642131613
# differential_evolution step 516: f(x)= 1963.702601946766
# differential_evolution step 517: f(x)= 1963.702601946766
# differential_evolution step 518: f(x)= 1963.702601946766
# differential_evolution step 519: f(x)= 1963.702601946766
# differential_evolution step 520: f(x)= 1963.702601946766
# differential_evolution step 521: f(x)= 1963.702601946766
# differential_evolution step 522: f(x)= 1963.702601946766
# differential_evolution step 523: f(x)= 1963.702601946766
# differential_evolution step 524: f(x)= 1963.702601946766
# differential_evolution step 525: f(x)= 1963.702601946766
# differential_evolution step 526: f(x)= 1963.702601946766
# differential_evolution step 527: f(x)= 1963.702601946766
# differential_evolution step 528: f(x)= 1963.702601946766
# differential_evolution step 529: f(x)= 1963.702601946766
# differential_evolution step 530: f(x)= 1963.702601946766
# differential_evolution step 531: f(x)= 1963.6292460609905
# differential_evolution step 532: f(x)= 1963.6292460609905
# differential_evolution step 533: f(x)= 1963.6292460609905
# differential_evolution step 534: f(x)= 1963.6292460609905
# differential_evolution step 535: f(x)= 1963.6292460609905
# differential_evolution step 536: f(x)= 1963.6292460609905
# differential_evolution step 537: f(x)= 1963.6292460609905
# differential_evolution step 538: f(x)= 1963.6292460609905
# differential_evolution step 539: f(x)= 1963.6292460609905
# differential_evolution step 540: f(x)= 1963.6292460609905
# differential_evolution step 541: f(x)= 1963.6292460609905
# differential_evolution step 542: f(x)= 1963.6292460609905
# differential_evolution step 543: f(x)= 1963.6292460609905
# differential_evolution step 544: f(x)= 1963.6292460609905
# differential_evolution step 545: f(x)= 1963.6292460609905
# differential_evolution step 546: f(x)= 1963.6292460609905
# differential_evolution step 547: f(x)= 1963.6292460609905
# differential_evolution step 548: f(x)= 1963.6292460609905
# differential_evolution step 549: f(x)= 1963.6292460609905
# differential_evolution step 550: f(x)= 1963.6292460609905
# differential_evolution step 551: f(x)= 1963.6292460609905
# differential_evolution step 552: f(x)= 1963.6292460609905
# differential_evolution step 553: f(x)= 1963.6292460609905
# differential_evolution step 554: f(x)= 1963.6292460609905
# differential_evolution step 555: f(x)= 1963.6292460609905
# differential_evolution step 556: f(x)= 1963.6292460609905
# differential_evolution step 557: f(x)= 1963.6292460609905
# differential_evolution step 558: f(x)= 1963.6292460609905
# differential_evolution step 559: f(x)= 1963.6292460609905
# differential_evolution step 560: f(x)= 1963.6292460609905
# differential_evolution step 561: f(x)= 1963.6292460609905
# differential_evolution step 562: f(x)= 1963.6292460609905
# differential_evolution step 563: f(x)= 1963.622436316465
# differential_evolution step 564: f(x)= 1963.622436316465
# differential_evolution step 565: f(x)= 1963.622436316465
# differential_evolution step 566: f(x)= 1963.622436316465
# differential_evolution step 567: f(x)= 1963.622436316465
# differential_evolution step 568: f(x)= 1963.622436316465
# differential_evolution step 569: f(x)= 1963.6075275342748
# differential_evolution step 570: f(x)= 1963.6075275342748
# differential_evolution step 571: f(x)= 1963.6070481459603
# differential_evolution step 572: f(x)= 1963.6070481459603
# differential_evolution step 573: f(x)= 1963.6070481459603
# differential_evolution step 574: f(x)= 1963.6070481459603
# differential_evolution step 575: f(x)= 1963.6070481459603
# differential_evolution step 576: f(x)= 1963.6070481459603
# differential_evolution step 577: f(x)= 1963.6070481459603
# differential_evolution step 578: f(x)= 1963.5852946380044
# differential_evolution step 579: f(x)= 1963.5852946380044
# differential_evolution step 580: f(x)= 1963.5852946380044
# differential_evolution step 581: f(x)= 1963.5852946380044
# differential_evolution step 582: f(x)= 1963.5772561463784
# differential_evolution step 583: f(x)= 1963.5772561463784
# differential_evolution step 584: f(x)= 1963.5754197245083
# differential_evolution step 585: f(x)= 1963.5754197245083
# differential_evolution step 586: f(x)= 1963.5754197245083
# differential_evolution step 587: f(x)= 1963.5754197245083
# differential_evolution step 588: f(x)= 1963.5754197245083
# differential_evolution step 589: f(x)= 1963.5754197245083
# differential_evolution step 590: f(x)= 1963.5754197245083
# differential_evolution step 591: f(x)= 1963.5754197245083
# differential_evolution step 592: f(x)= 1963.5754197245083
# differential_evolution step 593: f(x)= 1963.5754197245083
# differential_evolution step 594: f(x)= 1963.5711562328008
# differential_evolution step 595: f(x)= 1963.5711562328008
# differential_evolution step 596: f(x)= 1963.5711562328008
# differential_evolution step 597: f(x)= 1963.5711562328008
# differential_evolution step 598: f(x)= 1963.5548283648711
# differential_evolution step 599: f(x)= 1963.5548283648711
# differential_evolution step 600: f(x)= 1963.5548283648711
# differential_evolution step 601: f(x)= 1963.5548283648711
# differential_evolution step 602: f(x)= 1963.5548283648711
# differential_evolution step 603: f(x)= 1963.5548283648711
# differential_evolution step 604: f(x)= 1963.5548283648711
# differential_evolution step 605: f(x)= 1963.5548283648711
# differential_evolution step 606: f(x)= 1963.5548283648711
# differential_evolution step 607: f(x)= 1963.5548283648711
# differential_evolution step 608: f(x)= 1963.5548283648711
# differential_evolution step 609: f(x)= 1963.5548283648711
# differential_evolution step 610: f(x)= 1963.554113425722
# differential_evolution step 611: f(x)= 1963.554113425722
# differential_evolution step 612: f(x)= 1963.554113425722
# differential_evolution step 613: f(x)= 1963.5437046817742
# differential_evolution step 614: f(x)= 1963.5437046817742
# differential_evolution step 615: f(x)= 1963.5437046817742
# differential_evolution step 616: f(x)= 1963.5437046817742
# differential_evolution step 617: f(x)= 1963.5437046817742
# differential_evolution step 618: f(x)= 1963.5437046817742
# differential_evolution step 619: f(x)= 1963.5437046817742
# differential_evolution step 620: f(x)= 1963.5437046817742
# differential_evolution step 621: f(x)= 1963.5437046817742
# differential_evolution step 622: f(x)= 1963.5437046817742
# differential_evolution step 623: f(x)= 1963.5437046817742
# differential_evolution step 624: f(x)= 1963.5437046817742
# differential_evolution step 625: f(x)= 1963.5437046817742
# differential_evolution step 626: f(x)= 1963.5437046817742
# differential_evolution step 627: f(x)= 1963.5437046817742
# differential_evolution step 628: f(x)= 1963.5437046817742
# differential_evolution step 629: f(x)= 1963.5437046817742
# differential_evolution step 630: f(x)= 1963.5437046817742
# differential_evolution step 631: f(x)= 1963.5372314109252
# differential_evolution step 632: f(x)= 1963.5372314109252
# differential_evolution step 633: f(x)= 1963.5372314109252
# differential_evolution step 634: f(x)= 1963.5372314109252
# differential_evolution step 635: f(x)= 1963.5372314109252
# differential_evolution step 636: f(x)= 1963.5372314109252
# differential_evolution step 637: f(x)= 1963.5372314109252
# differential_evolution step 638: f(x)= 1963.5372314109252
# differential_evolution step 639: f(x)= 1963.5371434543622
# differential_evolution step 640: f(x)= 1963.5371434543622
# differential_evolution step 641: f(x)= 1963.5371434543622
# differential_evolution step 642: f(x)= 1963.5371434543622
# differential_evolution step 643: f(x)= 1963.5371434543622
# differential_evolution step 644: f(x)= 1963.5371434543622
# differential_evolution step 645: f(x)= 1963.5371434543622
# differential_evolution step 646: f(x)= 1963.5363108429117
# differential_evolution step 647: f(x)= 1963.5356606628545
# differential_evolution step 648: f(x)= 1963.5347287747582
# differential_evolution step 649: f(x)= 1963.5347287747582
# differential_evolution step 650: f(x)= 1963.5347287747582
# differential_evolution step 651: f(x)= 1963.5347287747582
# differential_evolution step 652: f(x)= 1963.5347287747582
# differential_evolution step 653: f(x)= 1963.531291407571
# differential_evolution step 654: f(x)= 1963.531291407571
# differential_evolution step 655: f(x)= 1963.531291407571
# differential_evolution step 656: f(x)= 1963.531291407571
# differential_evolution step 657: f(x)= 1963.531291407571
# differential_evolution step 658: f(x)= 1963.531291407571
# differential_evolution step 659: f(x)= 1963.5294214196745
# differential_evolution step 660: f(x)= 1963.5294214196745
# differential_evolution step 661: f(x)= 1963.5294214196745
# differential_evolution step 662: f(x)= 1963.5294214196745
# differential_evolution step 663: f(x)= 1963.5294214196745
# differential_evolution step 664: f(x)= 1963.5278253098227
# differential_evolution step 665: f(x)= 1963.5278253098227
# differential_evolution step 666: f(x)= 1963.5278253098227
# differential_evolution step 667: f(x)= 1963.5278253098227
# differential_evolution step 668: f(x)= 1963.5267672221187
# differential_evolution step 669: f(x)= 1963.5267672221187
# differential_evolution step 670: f(x)= 1963.5267672221187
# differential_evolution step 671: f(x)= 1963.5267672221187
# differential_evolution step 672: f(x)= 1963.5267672221187
# differential_evolution step 673: f(x)= 1963.5267672221187
# differential_evolution step 674: f(x)= 1963.5267672221187
# differential_evolution step 675: f(x)= 1963.5267672221187
# differential_evolution step 676: f(x)= 1963.5267672221187
# differential_evolution step 677: f(x)= 1963.5267672221187
# differential_evolution step 678: f(x)= 1963.5267672221187
# differential_evolution step 679: f(x)= 1963.5267672221187
# differential_evolution step 680: f(x)= 1963.5267672221187
# differential_evolution step 681: f(x)= 1963.5267672221187
# differential_evolution step 682: f(x)= 1963.5267672221187
# differential_evolution step 683: f(x)= 1963.5267672221187
# differential_evolution step 684: f(x)= 1963.5267672221187
# differential_evolution step 685: f(x)= 1963.5267672221187
# differential_evolution step 686: f(x)= 1963.5267672221187
# differential_evolution step 687: f(x)= 1963.5267672221187
# differential_evolution step 688: f(x)= 1963.5267672221187
# differential_evolution step 689: f(x)= 1963.5267672221187
# differential_evolution step 690: f(x)= 1963.5267672221187
# differential_evolution step 691: f(x)= 1963.526521372581
# differential_evolution step 692: f(x)= 1963.526521372581
# differential_evolution step 693: f(x)= 1963.526521372581
# differential_evolution step 694: f(x)= 1963.526521372581
# differential_evolution step 695: f(x)= 1963.526521372581
# differential_evolution step 696: f(x)= 1963.526521372581
# differential_evolution step 697: f(x)= 1963.526521372581
# differential_evolution step 698: f(x)= 1963.526164346887
# differential_evolution step 699: f(x)= 1963.5246278616173
# differential_evolution step 700: f(x)= 1963.5246278616173
# differential_evolution step 701: f(x)= 1963.5246278616173
# differential_evolution step 702: f(x)= 1963.5246278616173
# differential_evolution step 703: f(x)= 1963.5246278616173
# differential_evolution step 704: f(x)= 1963.5246278616173
# differential_evolution step 705: f(x)= 1963.5246278616173
# differential_evolution step 706: f(x)= 1963.5246278616173
# differential_evolution step 707: f(x)= 1963.5246278616173
# differential_evolution step 708: f(x)= 1963.5245947864134
# differential_evolution step 709: f(x)= 1963.5245947864134
# differential_evolution step 710: f(x)= 1963.524410473113
# differential_evolution step 711: f(x)= 1963.524410473113
# differential_evolution step 712: f(x)= 1963.524410473113
# differential_evolution step 713: f(x)= 1963.524410473113
# differential_evolution step 714: f(x)= 1963.524410473113
# differential_evolution step 715: f(x)= 1963.524410473113
# differential_evolution step 716: f(x)= 1963.524410473113
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=17.4626, r_e=12.9737, n=1.6239, x_0=44.3956
# Sérsic 2: I_e=20.0000, r_e=6.6158, n=0.1000, x_0=48.6487
# Sérsic 3: I_e=20.0000, r_e=10.4483, n=1.7327, x_0=57.0000
# Chi quadro minimo: 1963.523395891952
# True

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[5], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = radial_profile_error_continuum_2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2, radial_profile_error_continuum_2,
                                                                          sigmas[5], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=6.5247, r_e=26.9750, n=2.3363, x_0=44.5252
# Sérsic 2: I_e=19.9999, r_e=6.8756, n=0.1000, x_0=48.1288
# Sérsic 3: I_e=20.0000, r_e=9.1813, n=1.7898, x_0=57.0000
# [ 1.71984724  4.70679459  0.18869906  0.11159046 14.34265502  5.93957244
#   0.17799272  6.21502112  4.35704576  1.23729168  0.26228861  0.39537681]
# 987.5431686819434

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, sigmas[5], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 44596.05584466128
# differential_evolution step 2: f(x)= 16203.405468582587
# differential_evolution step 3: f(x)= 16203.405468582587
# differential_evolution step 4: f(x)= 16203.405468582587
# differential_evolution step 5: f(x)= 16203.405468582587
# differential_evolution step 6: f(x)= 7551.849955584898
# differential_evolution step 7: f(x)= 7551.849955584898
# differential_evolution step 8: f(x)= 7551.849955584898
# differential_evolution step 9: f(x)= 7551.849955584898
# differential_evolution step 10: f(x)= 7551.849955584898
# differential_evolution step 11: f(x)= 7551.849955584898
# differential_evolution step 12: f(x)= 7551.849955584898
# differential_evolution step 13: f(x)= 6484.968416289039
# differential_evolution step 14: f(x)= 6484.968416289039
# differential_evolution step 15: f(x)= 6431.725186199109
# differential_evolution step 16: f(x)= 6431.725186199109
# differential_evolution step 17: f(x)= 6431.725186199109
# differential_evolution step 18: f(x)= 5808.911738259383
# differential_evolution step 19: f(x)= 5808.911738259383
# differential_evolution step 20: f(x)= 4879.596364141313
# differential_evolution step 21: f(x)= 4879.596364141313
# differential_evolution step 22: f(x)= 4131.979093270754
# differential_evolution step 23: f(x)= 4131.979093270754
# differential_evolution step 24: f(x)= 4024.752597053383
# differential_evolution step 25: f(x)= 4024.752597053383
# differential_evolution step 26: f(x)= 3435.123420740841
# differential_evolution step 27: f(x)= 3435.123420740841
# differential_evolution step 28: f(x)= 3435.123420740841
# differential_evolution step 29: f(x)= 3424.8834937346073
# differential_evolution step 30: f(x)= 3424.8834937346073
# differential_evolution step 31: f(x)= 3417.887463742669
# differential_evolution step 32: f(x)= 2759.723144062805
# differential_evolution step 33: f(x)= 2759.723144062805
# differential_evolution step 34: f(x)= 2457.5814951805733
# differential_evolution step 35: f(x)= 2457.5814951805733
# differential_evolution step 36: f(x)= 2457.5814951805733
# differential_evolution step 37: f(x)= 2457.5814951805733
# differential_evolution step 38: f(x)= 2344.679700096461
# differential_evolution step 39: f(x)= 2344.679700096461
# differential_evolution step 40: f(x)= 2212.3325334329966
# differential_evolution step 41: f(x)= 2097.5262165439212
# differential_evolution step 42: f(x)= 2001.6057437805962
# differential_evolution step 43: f(x)= 2001.6057437805962
# differential_evolution step 44: f(x)= 1867.5259476689719
# differential_evolution step 45: f(x)= 1867.5259476689719
# differential_evolution step 46: f(x)= 1867.5259476689719
# differential_evolution step 47: f(x)= 1867.5259476689719
# differential_evolution step 48: f(x)= 1867.5259476689719
# differential_evolution step 49: f(x)= 1867.5259476689719
# differential_evolution step 50: f(x)= 1867.5259476689719
# differential_evolution step 51: f(x)= 1867.5259476689719
# differential_evolution step 52: f(x)= 1712.454126144362
# differential_evolution step 53: f(x)= 1712.454126144362
# differential_evolution step 54: f(x)= 1712.454126144362
# differential_evolution step 55: f(x)= 1712.454126144362
# differential_evolution step 56: f(x)= 1712.454126144362
# differential_evolution step 57: f(x)= 1712.454126144362
# differential_evolution step 58: f(x)= 1712.454126144362
# differential_evolution step 59: f(x)= 1712.454126144362
# differential_evolution step 60: f(x)= 1712.454126144362
# differential_evolution step 61: f(x)= 1712.454126144362
# differential_evolution step 62: f(x)= 1712.454126144362
# differential_evolution step 63: f(x)= 1712.454126144362
# differential_evolution step 64: f(x)= 1712.454126144362
# differential_evolution step 65: f(x)= 1712.454126144362
# differential_evolution step 66: f(x)= 1544.303286173404
# differential_evolution step 67: f(x)= 1544.303286173404
# differential_evolution step 68: f(x)= 1544.303286173404
# differential_evolution step 69: f(x)= 1377.1253797084808
# differential_evolution step 70: f(x)= 1377.1253797084808
# differential_evolution step 71: f(x)= 1377.1253797084808
# differential_evolution step 72: f(x)= 1377.1253797084808
# differential_evolution step 73: f(x)= 1377.1253797084808
# differential_evolution step 74: f(x)= 1354.3830644808543
# differential_evolution step 75: f(x)= 1354.3830644808543
# differential_evolution step 76: f(x)= 1354.3830644808543
# differential_evolution step 77: f(x)= 1326.1218470753995
# differential_evolution step 78: f(x)= 1324.8281859175777
# differential_evolution step 79: f(x)= 1204.926183213567
# differential_evolution step 80: f(x)= 1204.926183213567
# differential_evolution step 81: f(x)= 1204.926183213567
# differential_evolution step 82: f(x)= 1204.926183213567
# differential_evolution step 83: f(x)= 1204.926183213567
# differential_evolution step 84: f(x)= 1204.926183213567
# differential_evolution step 85: f(x)= 1204.926183213567
# differential_evolution step 86: f(x)= 1204.926183213567
# differential_evolution step 87: f(x)= 1204.926183213567
# differential_evolution step 88: f(x)= 1204.926183213567
# differential_evolution step 89: f(x)= 1204.926183213567
# differential_evolution step 90: f(x)= 1102.592185755165
# differential_evolution step 91: f(x)= 1102.592185755165
# differential_evolution step 92: f(x)= 1102.592185755165
# differential_evolution step 93: f(x)= 1102.592185755165
# differential_evolution step 94: f(x)= 1102.592185755165
# differential_evolution step 95: f(x)= 1102.592185755165
# differential_evolution step 96: f(x)= 1102.592185755165
# differential_evolution step 97: f(x)= 1102.592185755165
# differential_evolution step 98: f(x)= 1102.592185755165
# differential_evolution step 99: f(x)= 1102.592185755165
# differential_evolution step 100: f(x)= 1102.592185755165
# differential_evolution step 101: f(x)= 1102.592185755165
# differential_evolution step 102: f(x)= 1102.592185755165
# differential_evolution step 103: f(x)= 1102.592185755165
# differential_evolution step 104: f(x)= 1102.592185755165
# differential_evolution step 105: f(x)= 1102.592185755165
# differential_evolution step 106: f(x)= 1102.592185755165
# differential_evolution step 107: f(x)= 1102.592185755165
# differential_evolution step 108: f(x)= 1102.592185755165
# differential_evolution step 109: f(x)= 1102.592185755165
# differential_evolution step 110: f(x)= 1102.592185755165
# differential_evolution step 111: f(x)= 1102.592185755165
# differential_evolution step 112: f(x)= 1102.592185755165
# differential_evolution step 113: f(x)= 1102.592185755165
# differential_evolution step 114: f(x)= 1102.592185755165
# differential_evolution step 115: f(x)= 1092.1325687229737
# differential_evolution step 116: f(x)= 1092.1325687229737
# differential_evolution step 117: f(x)= 1092.1325687229737
# differential_evolution step 118: f(x)= 1092.1325687229737
# differential_evolution step 119: f(x)= 1092.1325687229737
# differential_evolution step 120: f(x)= 1092.1325687229737
# differential_evolution step 121: f(x)= 1092.1325687229737
# differential_evolution step 122: f(x)= 1092.1325687229737
# differential_evolution step 123: f(x)= 1076.0188007117385
# differential_evolution step 124: f(x)= 1076.0188007117385
# differential_evolution step 125: f(x)= 1076.0188007117385
# differential_evolution step 126: f(x)= 1076.0188007117385
# differential_evolution step 127: f(x)= 1076.0188007117385
# differential_evolution step 128: f(x)= 1076.0188007117385
# differential_evolution step 129: f(x)= 1076.0188007117385
# differential_evolution step 130: f(x)= 1076.0188007117385
# differential_evolution step 131: f(x)= 1071.2982495745623
# differential_evolution step 132: f(x)= 1071.2982495745623
# differential_evolution step 133: f(x)= 1071.2982495745623
# differential_evolution step 134: f(x)= 1071.2982495745623
# differential_evolution step 135: f(x)= 1071.2982495745623
# differential_evolution step 136: f(x)= 1071.2982495745623
# differential_evolution step 137: f(x)= 1071.2982495745623
# differential_evolution step 138: f(x)= 1071.2982495745623
# differential_evolution step 139: f(x)= 1071.2982495745623
# differential_evolution step 140: f(x)= 1071.2982495745623
# differential_evolution step 141: f(x)= 1071.2982495745623
# differential_evolution step 142: f(x)= 1071.2982495745623
# differential_evolution step 143: f(x)= 1067.7107084463976
# differential_evolution step 144: f(x)= 1067.7107084463976
# differential_evolution step 145: f(x)= 1067.7107084463976
# differential_evolution step 146: f(x)= 1063.2504678315986
# differential_evolution step 147: f(x)= 1063.2504678315986
# differential_evolution step 148: f(x)= 1062.3578660150952
# differential_evolution step 149: f(x)= 1048.8480634833732
# differential_evolution step 150: f(x)= 1048.8480634833732
# differential_evolution step 151: f(x)= 1048.8480634833732
# differential_evolution step 152: f(x)= 1048.8480634833732
# differential_evolution step 153: f(x)= 1048.8480634833732
# differential_evolution step 154: f(x)= 1048.8480634833732
# differential_evolution step 155: f(x)= 1048.8480634833732
# differential_evolution step 156: f(x)= 1048.8480634833732
# differential_evolution step 157: f(x)= 1048.8480634833732
# differential_evolution step 158: f(x)= 1048.8480634833732
# differential_evolution step 159: f(x)= 1043.9132733490603
# differential_evolution step 160: f(x)= 1043.9132733490603
# differential_evolution step 161: f(x)= 1043.9132733490603
# differential_evolution step 162: f(x)= 1043.9132733490603
# differential_evolution step 163: f(x)= 1043.9132733490603
# differential_evolution step 164: f(x)= 1043.9132733490603
# differential_evolution step 165: f(x)= 1043.9132733490603
# differential_evolution step 166: f(x)= 1043.9132733490603
# differential_evolution step 167: f(x)= 1043.9132733490603
# differential_evolution step 168: f(x)= 1043.9132733490603
# differential_evolution step 169: f(x)= 1043.9132733490603
# differential_evolution step 170: f(x)= 1041.5954112420577
# differential_evolution step 171: f(x)= 1041.5954112420577
# differential_evolution step 172: f(x)= 1041.5954112420577
# differential_evolution step 173: f(x)= 1039.463521060995
# differential_evolution step 174: f(x)= 1039.463521060995
# differential_evolution step 175: f(x)= 1039.463521060995
# differential_evolution step 176: f(x)= 1039.463521060995
# differential_evolution step 177: f(x)= 1039.463521060995
# differential_evolution step 178: f(x)= 1039.463521060995
# differential_evolution step 179: f(x)= 1039.463521060995
# differential_evolution step 180: f(x)= 1039.463521060995
# differential_evolution step 181: f(x)= 1035.3205132946516
# differential_evolution step 182: f(x)= 1035.3205132946516
# differential_evolution step 183: f(x)= 1035.3205132946516
# differential_evolution step 184: f(x)= 1035.3205132946516
# differential_evolution step 185: f(x)= 1034.053598223272
# differential_evolution step 186: f(x)= 1031.5248286996903
# differential_evolution step 187: f(x)= 1031.5248286996903
# differential_evolution step 188: f(x)= 1031.5248286996903
# differential_evolution step 189: f(x)= 1031.5248286996903
# differential_evolution step 190: f(x)= 1031.5248286996903
# differential_evolution step 191: f(x)= 1031.5248286996903
# differential_evolution step 192: f(x)= 1031.5248286996903
# differential_evolution step 193: f(x)= 1031.5248286996903
# differential_evolution step 194: f(x)= 1031.5248286996903
# differential_evolution step 195: f(x)= 1031.5248286996903
# differential_evolution step 196: f(x)= 1031.5248286996903
# differential_evolution step 197: f(x)= 1031.5248286996903
# differential_evolution step 198: f(x)= 1031.5248286996903
# differential_evolution step 199: f(x)= 1031.5248286996903
# differential_evolution step 200: f(x)= 1031.5248286996903
# differential_evolution step 201: f(x)= 1031.5248286996903
# differential_evolution step 202: f(x)= 1031.5248286996903
# differential_evolution step 203: f(x)= 1031.5248286996903
# differential_evolution step 204: f(x)= 1031.5248286996903
# differential_evolution step 205: f(x)= 1031.5248286996903
# differential_evolution step 206: f(x)= 1031.5248286996903
# differential_evolution step 207: f(x)= 1031.5248286996903
# differential_evolution step 208: f(x)= 1031.5248286996903
# differential_evolution step 209: f(x)= 1027.1166100608616
# differential_evolution step 210: f(x)= 1027.1166100608616
# differential_evolution step 211: f(x)= 1027.1166100608616
# differential_evolution step 212: f(x)= 1027.1166100608616
# differential_evolution step 213: f(x)= 1027.1166100608616
# differential_evolution step 214: f(x)= 1027.1166100608616
# differential_evolution step 215: f(x)= 1027.1166100608616
# differential_evolution step 216: f(x)= 1027.1166100608616
# differential_evolution step 217: f(x)= 1027.1166100608616
# differential_evolution step 218: f(x)= 1027.1166100608616
# differential_evolution step 219: f(x)= 1027.1166100608616
# differential_evolution step 220: f(x)= 1027.1166100608616
# differential_evolution step 221: f(x)= 1026.9672109877692
# differential_evolution step 222: f(x)= 1026.9672109877692
# differential_evolution step 223: f(x)= 1026.9672109877692
# differential_evolution step 224: f(x)= 1026.9672109877692
# differential_evolution step 225: f(x)= 1025.6545170665397
# differential_evolution step 226: f(x)= 1025.6545170665397
# differential_evolution step 227: f(x)= 1025.6545170665397
# differential_evolution step 228: f(x)= 1025.6545170665397
# differential_evolution step 229: f(x)= 1025.6545170665397
# differential_evolution step 230: f(x)= 1025.6545170665397
# differential_evolution step 231: f(x)= 1025.6545170665397
# differential_evolution step 232: f(x)= 1025.6545170665397
# differential_evolution step 233: f(x)= 1025.6545170665397
# differential_evolution step 234: f(x)= 1025.6545170665397
# differential_evolution step 235: f(x)= 1025.6545170665397
# differential_evolution step 236: f(x)= 1025.3743401220172
# differential_evolution step 237: f(x)= 1024.5506131775871
# differential_evolution step 238: f(x)= 1024.5506131775871
# differential_evolution step 239: f(x)= 1024.5506131775871
# differential_evolution step 240: f(x)= 1024.5506131775871
# differential_evolution step 241: f(x)= 1024.5506131775871
# differential_evolution step 242: f(x)= 1024.2133706334268
# differential_evolution step 243: f(x)= 1024.2133706334268
# differential_evolution step 244: f(x)= 1024.131988017821
# differential_evolution step 245: f(x)= 1024.131988017821
# differential_evolution step 246: f(x)= 1023.9973003769824
# differential_evolution step 247: f(x)= 1023.9973003769824
# differential_evolution step 248: f(x)= 1023.9973003769824
# differential_evolution step 249: f(x)= 1023.9973003769824
# differential_evolution step 250: f(x)= 1023.9973003769824
# differential_evolution step 251: f(x)= 1023.9973003769824
# differential_evolution step 252: f(x)= 1023.3206198462306
# differential_evolution step 253: f(x)= 1023.3206198462306
# differential_evolution step 254: f(x)= 1023.1119167774737
# differential_evolution step 255: f(x)= 1023.1119167774737
# differential_evolution step 256: f(x)= 1023.1119167774737
# differential_evolution step 257: f(x)= 1023.1119167774737
# differential_evolution step 258: f(x)= 1023.1119167774737
# differential_evolution step 259: f(x)= 1023.1119167774737
# differential_evolution step 260: f(x)= 1023.1119167774737
# differential_evolution step 261: f(x)= 1023.1119167774737
# differential_evolution step 262: f(x)= 1023.1119167774737
# differential_evolution step 263: f(x)= 1023.1119167774737
# differential_evolution step 264: f(x)= 1023.1119167774737
# differential_evolution step 265: f(x)= 1023.1119167774737
# differential_evolution step 266: f(x)= 1023.1119167774737
# differential_evolution step 267: f(x)= 1022.9511247285769
# differential_evolution step 268: f(x)= 1022.9511247285769
# differential_evolution step 269: f(x)= 1022.853084625585
# differential_evolution step 270: f(x)= 1022.853084625585
# differential_evolution step 271: f(x)= 1022.6307346651026
# differential_evolution step 272: f(x)= 1022.6307346651026
# differential_evolution step 273: f(x)= 1022.6307346651026
# differential_evolution step 274: f(x)= 1022.532296463316
# differential_evolution step 275: f(x)= 1022.532296463316
# differential_evolution step 276: f(x)= 1022.532296463316
# differential_evolution step 277: f(x)= 1022.532296463316
# differential_evolution step 278: f(x)= 1022.532296463316
# differential_evolution step 279: f(x)= 1022.532296463316
# differential_evolution step 280: f(x)= 1022.532296463316
# differential_evolution step 281: f(x)= 1022.532296463316
# differential_evolution step 282: f(x)= 1022.532296463316
# differential_evolution step 283: f(x)= 1022.532296463316
# differential_evolution step 284: f(x)= 1022.532296463316
# differential_evolution step 285: f(x)= 1022.532296463316
# differential_evolution step 286: f(x)= 1022.532296463316
# differential_evolution step 287: f(x)= 1022.5261052998425
# differential_evolution step 288: f(x)= 1022.5261052998425
# differential_evolution step 289: f(x)= 1022.5261052998425
# differential_evolution step 290: f(x)= 1022.5261052998425
# differential_evolution step 291: f(x)= 1022.5261052998425
# differential_evolution step 292: f(x)= 1022.5261052998425
# differential_evolution step 293: f(x)= 1022.5261052998425
# differential_evolution step 294: f(x)= 1022.3907187470937
# differential_evolution step 295: f(x)= 1022.3907187470937
# differential_evolution step 296: f(x)= 1022.348044152268
# differential_evolution step 297: f(x)= 1022.348044152268
# differential_evolution step 298: f(x)= 1022.348044152268
# differential_evolution step 299: f(x)= 1022.348044152268
# differential_evolution step 300: f(x)= 1022.348044152268
# differential_evolution step 301: f(x)= 1022.348044152268
# differential_evolution step 302: f(x)= 1022.348044152268
# differential_evolution step 303: f(x)= 1022.348044152268
# differential_evolution step 304: f(x)= 1022.348044152268
# differential_evolution step 305: f(x)= 1022.348044152268
# differential_evolution step 306: f(x)= 1022.348044152268
# differential_evolution step 307: f(x)= 1022.348044152268
# differential_evolution step 308: f(x)= 1022.348044152268
# differential_evolution step 309: f(x)= 1022.348044152268
# differential_evolution step 310: f(x)= 1022.348044152268
# differential_evolution step 311: f(x)= 1022.348044152268
# differential_evolution step 312: f(x)= 1022.348044152268
# differential_evolution step 313: f(x)= 1022.348044152268
# differential_evolution step 314: f(x)= 1022.348044152268
# differential_evolution step 315: f(x)= 1022.348044152268
# differential_evolution step 316: f(x)= 1022.348044152268
# differential_evolution step 317: f(x)= 1022.348044152268
# differential_evolution step 318: f(x)= 1022.348044152268
# differential_evolution step 319: f(x)= 1022.315812284813
# differential_evolution step 320: f(x)= 1022.315812284813
# differential_evolution step 321: f(x)= 1022.315812284813
# differential_evolution step 322: f(x)= 1022.315812284813
# differential_evolution step 323: f(x)= 1022.315812284813
# differential_evolution step 324: f(x)= 1022.2607903772109
# differential_evolution step 325: f(x)= 1022.2607903772109
# differential_evolution step 326: f(x)= 1022.2607903772109
# differential_evolution step 327: f(x)= 1022.2607903772109
# differential_evolution step 328: f(x)= 1022.2607903772109
# differential_evolution step 329: f(x)= 1022.2332942323222
# differential_evolution step 330: f(x)= 1022.2332942323222
# differential_evolution step 331: f(x)= 1022.2332942323222
# differential_evolution step 332: f(x)= 1022.2332942323222
# differential_evolution step 333: f(x)= 1022.2332942323222
# differential_evolution step 334: f(x)= 1022.2332942323222
# differential_evolution step 335: f(x)= 1022.2332942323222
# differential_evolution step 336: f(x)= 1022.2332942323222
# differential_evolution step 337: f(x)= 1022.2332942323222
# differential_evolution step 338: f(x)= 1022.2332942323222
# differential_evolution step 339: f(x)= 1022.2332942323222
# differential_evolution step 340: f(x)= 1022.2332942323222
# differential_evolution step 341: f(x)= 1022.2332942323222
# differential_evolution step 342: f(x)= 1022.2332942323222
# differential_evolution step 343: f(x)= 1022.2332942323222
# differential_evolution step 344: f(x)= 1022.2332942323222
# differential_evolution step 345: f(x)= 1022.2332942323222
# differential_evolution step 346: f(x)= 1022.2332942323222
# differential_evolution step 347: f(x)= 1022.2332942323222
# differential_evolution step 348: f(x)= 1022.1304800619451
# differential_evolution step 349: f(x)= 1022.1304800619451
# differential_evolution step 350: f(x)= 1022.1304800619451
# differential_evolution step 351: f(x)= 1022.1304800619451
# differential_evolution step 352: f(x)= 1022.1304800619451
# differential_evolution step 353: f(x)= 1022.1304800619451
# differential_evolution step 354: f(x)= 1022.1304800619451
# differential_evolution step 355: f(x)= 1022.1304800619451
# differential_evolution step 356: f(x)= 1022.1304800619451
# differential_evolution step 357: f(x)= 1022.1304800619451
# differential_evolution step 358: f(x)= 1022.1304800619451
# differential_evolution step 359: f(x)= 1022.1304800619451
# differential_evolution step 360: f(x)= 1022.1304800619451
# differential_evolution step 361: f(x)= 1022.1304800619451
# differential_evolution step 362: f(x)= 1022.1304800619451
# differential_evolution step 363: f(x)= 1022.1304800619451
# differential_evolution step 364: f(x)= 1022.1304800619451
# differential_evolution step 365: f(x)= 1022.1304800619451
# differential_evolution step 366: f(x)= 1022.1304800619451
# differential_evolution step 367: f(x)= 1022.1304800619451
# differential_evolution step 368: f(x)= 1022.1304800619451
# differential_evolution step 369: f(x)= 1022.1304800619451
# differential_evolution step 370: f(x)= 1022.1304800619451
# differential_evolution step 371: f(x)= 1022.1304800619451
# differential_evolution step 372: f(x)= 1022.1304800619451
# differential_evolution step 373: f(x)= 1022.1304800619451
# differential_evolution step 374: f(x)= 1022.1304800619451
# differential_evolution step 375: f(x)= 1022.1304800619451
# differential_evolution step 376: f(x)= 1022.1304800619451
# differential_evolution step 377: f(x)= 1022.1304800619451
# differential_evolution step 378: f(x)= 1022.1304800619451
# differential_evolution step 379: f(x)= 1022.114962938194
# differential_evolution step 380: f(x)= 1022.114962938194
# differential_evolution step 381: f(x)= 1022.114962938194
# differential_evolution step 382: f(x)= 1022.114962938194
# differential_evolution step 383: f(x)= 1022.114962938194
# differential_evolution step 384: f(x)= 1022.114962938194
# differential_evolution step 385: f(x)= 1022.114962938194
# differential_evolution step 386: f(x)= 1022.114962938194
# differential_evolution step 387: f(x)= 1022.114962938194
# differential_evolution step 388: f(x)= 1022.114962938194
# differential_evolution step 389: f(x)= 1022.114962938194
# differential_evolution step 390: f(x)= 1022.114962938194
# differential_evolution step 391: f(x)= 1022.114962938194
# differential_evolution step 392: f(x)= 1022.114962938194
# differential_evolution step 393: f(x)= 1022.114962938194
# differential_evolution step 394: f(x)= 1022.114962938194
# differential_evolution step 395: f(x)= 1022.114962938194
# differential_evolution step 396: f(x)= 1022.114962938194
# differential_evolution step 397: f(x)= 1022.114962938194
# differential_evolution step 398: f(x)= 1022.114962938194
# differential_evolution step 399: f(x)= 1022.114962938194
# differential_evolution step 400: f(x)= 1022.114962938194
# differential_evolution step 401: f(x)= 1022.114962938194
# differential_evolution step 402: f(x)= 1022.114962938194
# differential_evolution step 403: f(x)= 1022.114962938194
# differential_evolution step 404: f(x)= 1022.114962938194
# differential_evolution step 405: f(x)= 1022.114962938194
# differential_evolution step 406: f(x)= 1022.114962938194
# differential_evolution step 407: f(x)= 1022.114962938194
# differential_evolution step 408: f(x)= 1022.114962938194
# differential_evolution step 409: f(x)= 1022.114962938194
# differential_evolution step 410: f(x)= 1022.114962938194
# differential_evolution step 411: f(x)= 1022.114962938194
# differential_evolution step 412: f(x)= 1022.114962938194
# differential_evolution step 413: f(x)= 1022.114962938194
# differential_evolution step 414: f(x)= 1022.114962938194
# differential_evolution step 415: f(x)= 1022.1110298429429
# differential_evolution step 416: f(x)= 1022.1110298429429
# differential_evolution step 417: f(x)= 1022.1110298429429
# differential_evolution step 418: f(x)= 1022.1110298429429
# differential_evolution step 419: f(x)= 1022.1110298429429
# differential_evolution step 420: f(x)= 1022.1110298429429
# differential_evolution step 421: f(x)= 1022.1110298429429
# differential_evolution step 422: f(x)= 1022.1110298429429
# differential_evolution step 423: f(x)= 1022.1110298429429
# differential_evolution step 424: f(x)= 1022.1110298429429
# differential_evolution step 425: f(x)= 1022.1110298429429
# differential_evolution step 426: f(x)= 1022.1110298429429
# differential_evolution step 427: f(x)= 1022.1110298429429
# differential_evolution step 428: f(x)= 1022.1065863690319
# differential_evolution step 429: f(x)= 1022.1065863690319
# differential_evolution step 430: f(x)= 1022.1065863690319
# differential_evolution step 431: f(x)= 1022.1065863690319
# differential_evolution step 432: f(x)= 1022.1065863690319
# differential_evolution step 433: f(x)= 1022.1065863690319
# differential_evolution step 434: f(x)= 1022.1065863690319
# differential_evolution step 435: f(x)= 1022.1065863690319
# differential_evolution step 436: f(x)= 1022.1065863690319
# differential_evolution step 437: f(x)= 1022.0977645639457
# differential_evolution step 438: f(x)= 1022.0925876708985
# differential_evolution step 439: f(x)= 1022.0925876708985
# differential_evolution step 440: f(x)= 1022.0925876708985
# differential_evolution step 441: f(x)= 1022.0925876708985
# differential_evolution step 442: f(x)= 1022.0925876708985
# differential_evolution step 443: f(x)= 1022.0925876708985
# differential_evolution step 444: f(x)= 1022.0925876708985
# differential_evolution step 445: f(x)= 1022.0925876708985
# differential_evolution step 446: f(x)= 1022.0925876708985
# differential_evolution step 447: f(x)= 1022.0925876708985
# differential_evolution step 448: f(x)= 1022.0925876708985
# differential_evolution step 449: f(x)= 1022.0925876708985
# differential_evolution step 450: f(x)= 1022.0925876708985
# differential_evolution step 451: f(x)= 1022.0925876708985
# differential_evolution step 452: f(x)= 1022.0925876708985
# differential_evolution step 453: f(x)= 1022.0925876708985
# differential_evolution step 454: f(x)= 1022.0925876708985
# differential_evolution step 455: f(x)= 1022.0925876708985
# differential_evolution step 456: f(x)= 1022.0925876708985
# differential_evolution step 457: f(x)= 1022.0925876708985
# differential_evolution step 458: f(x)= 1022.0925876708985
# differential_evolution step 459: f(x)= 1022.0925876708985
# differential_evolution step 460: f(x)= 1022.0925876708985
# differential_evolution step 461: f(x)= 1022.0925876708985
# differential_evolution step 462: f(x)= 1022.0925876708985
# differential_evolution step 463: f(x)= 1022.0925876708985
# differential_evolution step 464: f(x)= 1022.0925876708985
# differential_evolution step 465: f(x)= 1022.0925876708985
# differential_evolution step 466: f(x)= 1022.0920990137422
# differential_evolution step 467: f(x)= 1022.0920990137422
# differential_evolution step 468: f(x)= 1022.0920990137422
# differential_evolution step 469: f(x)= 1022.0920990137422
# differential_evolution step 470: f(x)= 1022.0920990137422
# differential_evolution step 471: f(x)= 1022.0894993763904
# differential_evolution step 472: f(x)= 1022.0894993763904
# differential_evolution step 473: f(x)= 1022.0894993763904
# differential_evolution step 474: f(x)= 1022.0894993763904
# differential_evolution step 475: f(x)= 1022.0866771311665
# differential_evolution step 476: f(x)= 1022.0866771311665
# differential_evolution step 477: f(x)= 1022.0866771311665
# differential_evolution step 478: f(x)= 1022.0866771311665
# differential_evolution step 479: f(x)= 1022.0866771311665
# differential_evolution step 480: f(x)= 1022.0866771311665
# differential_evolution step 481: f(x)= 1022.0866771311665
# differential_evolution step 482: f(x)= 1022.0866771311665
# differential_evolution step 483: f(x)= 1022.0860545010323
# differential_evolution step 484: f(x)= 1022.0836738405488
# differential_evolution step 485: f(x)= 1022.0836738405488
# differential_evolution step 486: f(x)= 1022.0836738405488
# differential_evolution step 487: f(x)= 1022.0836738405488
# differential_evolution step 488: f(x)= 1022.0836738405488
# differential_evolution step 489: f(x)= 1022.0836738405488
# differential_evolution step 490: f(x)= 1022.0836738405488
# differential_evolution step 491: f(x)= 1022.0836738405488
# differential_evolution step 492: f(x)= 1022.0836738405488
# differential_evolution step 493: f(x)= 1022.0836738405488
# differential_evolution step 494: f(x)= 1022.0836738405488
# differential_evolution step 495: f(x)= 1022.0836738405488
# differential_evolution step 496: f(x)= 1022.0836738405488
# differential_evolution step 497: f(x)= 1022.0836738405488
# differential_evolution step 498: f(x)= 1022.0836738405488
# differential_evolution step 499: f(x)= 1022.0836738405488
# differential_evolution step 500: f(x)= 1022.0836738405488
# differential_evolution step 501: f(x)= 1022.0836738405488
# differential_evolution step 502: f(x)= 1022.0836738405488
# differential_evolution step 503: f(x)= 1022.0836738405488
# differential_evolution step 504: f(x)= 1022.0836738405488
# differential_evolution step 505: f(x)= 1022.0836738405488
# differential_evolution step 506: f(x)= 1022.0836738405488
# differential_evolution step 507: f(x)= 1022.0836738405488
# differential_evolution step 508: f(x)= 1022.0836738405488
# differential_evolution step 509: f(x)= 1022.0836738405488
# differential_evolution step 510: f(x)= 1022.0836738405488
# differential_evolution step 511: f(x)= 1022.0836738405488
# differential_evolution step 512: f(x)= 1022.0836738405488
# differential_evolution step 513: f(x)= 1022.0836738405488
# differential_evolution step 514: f(x)= 1022.0836738405488
# differential_evolution step 515: f(x)= 1022.0836738405488
# differential_evolution step 516: f(x)= 1022.0836738405488
# differential_evolution step 517: f(x)= 1022.082383248853
# differential_evolution step 518: f(x)= 1022.082383248853
# differential_evolution step 519: f(x)= 1022.082383248853
# differential_evolution step 520: f(x)= 1022.082383248853
# differential_evolution step 521: f(x)= 1022.082383248853
# differential_evolution step 522: f(x)= 1022.082383248853
# differential_evolution step 523: f(x)= 1022.082346292139
# differential_evolution step 524: f(x)= 1022.082346292139
# differential_evolution step 525: f(x)= 1022.082346292139
# differential_evolution step 526: f(x)= 1022.082346292139
# differential_evolution step 527: f(x)= 1022.082346292139
# differential_evolution step 528: f(x)= 1022.082346292139
# differential_evolution step 529: f(x)= 1022.082346292139
# differential_evolution step 530: f(x)= 1022.082346292139
# differential_evolution step 531: f(x)= 1022.0821740002509
# differential_evolution step 532: f(x)= 1022.0821740002509
# differential_evolution step 533: f(x)= 1022.0821740002509
# differential_evolution step 534: f(x)= 1022.0821740002509
# differential_evolution step 535: f(x)= 1022.0816962057246
# differential_evolution step 536: f(x)= 1022.0816962057246
# differential_evolution step 537: f(x)= 1022.0816962057246
# differential_evolution step 538: f(x)= 1022.0815457932939
# differential_evolution step 539: f(x)= 1022.0815457932939
# differential_evolution step 540: f(x)= 1022.0815457932939
# differential_evolution step 541: f(x)= 1022.0815457932939
# differential_evolution step 542: f(x)= 1022.0815457932939
# differential_evolution step 543: f(x)= 1022.0815457932939
# differential_evolution step 544: f(x)= 1022.0815457932939
# differential_evolution step 545: f(x)= 1022.0814605624065
# differential_evolution step 546: f(x)= 1022.0814605624065
# differential_evolution step 547: f(x)= 1022.0814605624065
# differential_evolution step 548: f(x)= 1022.0814605624065
# differential_evolution step 549: f(x)= 1022.081207096935
# differential_evolution step 550: f(x)= 1022.081207096935
# differential_evolution step 551: f(x)= 1022.081207096935
# differential_evolution step 552: f(x)= 1022.081207096935
# differential_evolution step 553: f(x)= 1022.081207096935
# differential_evolution step 554: f(x)= 1022.0811372868147
# differential_evolution step 555: f(x)= 1022.0811372868147
# differential_evolution step 556: f(x)= 1022.0811372868147
# differential_evolution step 557: f(x)= 1022.0811372868147
# differential_evolution step 558: f(x)= 1022.0810585307281
# differential_evolution step 559: f(x)= 1022.0810585307281
# differential_evolution step 560: f(x)= 1022.0810585307281
# differential_evolution step 561: f(x)= 1022.0810585307281
# differential_evolution step 562: f(x)= 1022.0810585307281
# differential_evolution step 563: f(x)= 1022.0810585307281
# differential_evolution step 564: f(x)= 1022.0810585307281
# differential_evolution step 565: f(x)= 1022.0810585307281
# differential_evolution step 566: f(x)= 1022.0810585307281
# differential_evolution step 567: f(x)= 1022.0810585307281
# differential_evolution step 568: f(x)= 1022.0810585307281
# differential_evolution step 569: f(x)= 1022.0810585307281
# differential_evolution step 570: f(x)= 1022.0809622474009
# differential_evolution step 571: f(x)= 1022.0809622474009
# differential_evolution step 572: f(x)= 1022.0809622474009
# differential_evolution step 573: f(x)= 1022.0809407948591
# differential_evolution step 574: f(x)= 1022.0809407948591
# differential_evolution step 575: f(x)= 1022.0809407948591
# differential_evolution step 576: f(x)= 1022.080890233559
# differential_evolution step 577: f(x)= 1022.080890233559
# differential_evolution step 578: f(x)= 1022.080890233559
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=3.2779, r_e=28.3836, n=2.1671, x_0=44.3538
# Sérsic 2: I_e=20.0000, r_e=8.4451, n=0.6743, x_0=52.3673
# Sérsic 3: I_e=20.0000, r_e=7.7034, n=0.9995, x_0=59.2850
# Chi quadro minimo: 1022.0803916370572
# True

# %%
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = radial_profile_error_continuum_3, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          radial_profile_error_continuum_3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.5775, r_e=49.8431, n=2.7083, x_0=44.3979
# Sérsic 2: I_e=20.0000, r_e=8.3161, n=0.7390, x_0=52.3878
# Sérsic 3: I_e=20.0000, r_e=6.7325, n=1.0192, x_0=59.4506
# [ 1.30710687 25.20529096  0.54763124  0.10976632  4.50898822  2.18132745
#   0.12559778  0.63128352  4.27753126  0.98416998  0.10734109  0.19771372]
# 483.5583291672541

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (10, 20),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 50),
    (0.1, 10),
    (35, 45),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (55, 65),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (60, 70),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (70, 80),

    (0, 1),
    (0, 50),
    (0.1, 10),
    (90, 100)
]

lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
