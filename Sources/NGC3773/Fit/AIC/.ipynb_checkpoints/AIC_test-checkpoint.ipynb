# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32

# %%
image_cut = image[70:170, 0:1890]
image_error_cut = image_error[70:170, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.00328
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/PSF/Real_seeing_NGC3773.txt")
sigma = seeing[0] / 2.35

# %%
l_HA
# Out:
# 6584.52664

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 9993.482530296758
# differential_evolution step 2: f(x)= 9524.617850580302
# differential_evolution step 3: f(x)= 9294.32086703104
# differential_evolution step 4: f(x)= 7673.954347969691
# differential_evolution step 5: f(x)= 7673.954347969691
# differential_evolution step 6: f(x)= 7063.515670029354
# differential_evolution step 7: f(x)= 6549.490377314946
# differential_evolution step 8: f(x)= 6549.490377314946
# differential_evolution step 9: f(x)= 6431.274041755915
# differential_evolution step 10: f(x)= 5898.344237330943
# differential_evolution step 11: f(x)= 5884.802403972369
# differential_evolution step 12: f(x)= 5884.802403972369
# differential_evolution step 13: f(x)= 5569.102197161193
# differential_evolution step 14: f(x)= 5569.102197161193
# differential_evolution step 15: f(x)= 5569.102197161193
# differential_evolution step 16: f(x)= 5569.102197161193
# differential_evolution step 17: f(x)= 5569.102197161193
# differential_evolution step 18: f(x)= 5569.102197161193
# differential_evolution step 19: f(x)= 5458.236730573297
# differential_evolution step 20: f(x)= 5458.236730573297
# differential_evolution step 21: f(x)= 5409.788238623536
# differential_evolution step 22: f(x)= 5332.088251255784
# differential_evolution step 23: f(x)= 5309.950374393326
# differential_evolution step 24: f(x)= 5309.950374393326
# differential_evolution step 25: f(x)= 5309.950374393326
# differential_evolution step 26: f(x)= 5300.44392264675
# differential_evolution step 27: f(x)= 5300.44392264675
# differential_evolution step 28: f(x)= 5298.384067402707
# differential_evolution step 29: f(x)= 5298.384067402707
# differential_evolution step 30: f(x)= 5298.384067402707
# differential_evolution step 31: f(x)= 5298.384067402707
# differential_evolution step 32: f(x)= 5293.321508863561
# differential_evolution step 33: f(x)= 5293.321508863561
# differential_evolution step 34: f(x)= 5284.250508014617
# differential_evolution step 35: f(x)= 5278.6657084033595
# differential_evolution step 36: f(x)= 5278.6657084033595
# differential_evolution step 37: f(x)= 5278.6657084033595
# differential_evolution step 38: f(x)= 5278.6657084033595
# differential_evolution step 39: f(x)= 5278.6657084033595
# differential_evolution step 40: f(x)= 5278.6657084033595
# differential_evolution step 41: f(x)= 5278.6657084033595
# differential_evolution step 42: f(x)= 5278.6657084033595
# differential_evolution step 43: f(x)= 5275.325021089763
# differential_evolution step 44: f(x)= 5273.1196982427855
# differential_evolution step 45: f(x)= 5273.1196982427855
# differential_evolution step 46: f(x)= 5273.1196982427855
# differential_evolution step 47: f(x)= 5273.1196982427855
# differential_evolution step 48: f(x)= 5273.1196982427855
# differential_evolution step 49: f(x)= 5270.920595994032
# differential_evolution step 50: f(x)= 5270.772135883962
# differential_evolution step 51: f(x)= 5270.260968470205
# differential_evolution step 52: f(x)= 5270.260968470205
# differential_evolution step 53: f(x)= 5270.260968470205
# differential_evolution step 54: f(x)= 5270.260968470205
# differential_evolution step 55: f(x)= 5270.260968470205
# differential_evolution step 56: f(x)= 5269.714036176323
# differential_evolution step 57: f(x)= 5269.714036176323
# differential_evolution step 58: f(x)= 5269.714036176323
# differential_evolution step 59: f(x)= 5269.714036176323
# differential_evolution step 60: f(x)= 5269.714036176323
# differential_evolution step 61: f(x)= 5269.714036176323
# differential_evolution step 62: f(x)= 5269.714036176323
# differential_evolution step 63: f(x)= 5269.714036176323
# differential_evolution step 64: f(x)= 5269.714036176323
# differential_evolution step 65: f(x)= 5269.692658183243
# differential_evolution step 66: f(x)= 5269.692658183243
# differential_evolution step 67: f(x)= 5269.692658183243
# differential_evolution step 68: f(x)= 5269.692658183243
# differential_evolution step 69: f(x)= 5269.692658183243
# differential_evolution step 70: f(x)= 5269.663929903346
# differential_evolution step 71: f(x)= 5269.663929903346
# differential_evolution step 72: f(x)= 5269.64784684425
# differential_evolution step 73: f(x)= 5269.64784684425
# differential_evolution step 74: f(x)= 5269.64784684425
# differential_evolution step 75: f(x)= 5269.637233109128
# differential_evolution step 76: f(x)= 5269.637233109128
# differential_evolution step 77: f(x)= 5269.630968184383
# differential_evolution step 78: f(x)= 5269.630968184383
# differential_evolution step 79: f(x)= 5269.628854108803
# differential_evolution step 80: f(x)= 5269.624792808617
# differential_evolution step 81: f(x)= 5269.624792808617
# differential_evolution step 82: f(x)= 5269.621487963894
# differential_evolution step 83: f(x)= 5269.620581234458
# differential_evolution step 84: f(x)= 5269.615569122612
# differential_evolution step 85: f(x)= 5269.615569122612
# differential_evolution step 86: f(x)= 5269.615569122612
# differential_evolution step 87: f(x)= 5269.614352702794
# differential_evolution step 88: f(x)= 5269.613744639409
# differential_evolution step 89: f(x)= 5269.613744639409
# differential_evolution step 90: f(x)= 5269.613744639409
# differential_evolution step 91: f(x)= 5269.613744639409
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [20.         10.95293761  0.4096315  53.        ]
# Chi quadro minimo: 5269.612129150099

# %%
aic = np.zeros(6)
bic = np.zeros(6)
chi_quadr = np.zeros(6)
chi_quadro = np.zeros(6)
red_chi = np.zeros(6)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=20.7452, r_e=9.2586, n=0.4573, x_0=56.0899
# [1.71299985 0.3147221  0.05591232 0.34324252]
# 3188.395265641286
# 3196.816318272865 0.0 3206.8159463852385 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62)
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 6684.136228345557
# differential_evolution step 2: f(x)= 2922.8404351849763
# differential_evolution step 3: f(x)= 2922.8404351849763
# differential_evolution step 4: f(x)= 2922.8404351849763
# differential_evolution step 5: f(x)= 2922.8404351849763
# differential_evolution step 6: f(x)= 2480.213471690756
# differential_evolution step 7: f(x)= 2480.213471690756
# differential_evolution step 8: f(x)= 2480.213471690756
# differential_evolution step 9: f(x)= 2480.213471690756
# differential_evolution step 10: f(x)= 1821.1984586624637
# differential_evolution step 11: f(x)= 1821.1984586624637
# differential_evolution step 12: f(x)= 1821.1984586624637
# differential_evolution step 13: f(x)= 1821.1984586624637
# differential_evolution step 14: f(x)= 1821.1984586624637
# differential_evolution step 15: f(x)= 1819.9775487829888
# differential_evolution step 16: f(x)= 1652.2590346339887
# differential_evolution step 17: f(x)= 1652.2590346339887
# differential_evolution step 18: f(x)= 1057.3419042878807
# differential_evolution step 19: f(x)= 1057.3419042878807
# differential_evolution step 20: f(x)= 1057.3419042878807
# differential_evolution step 21: f(x)= 757.7690570877016
# differential_evolution step 22: f(x)= 757.7690570877016
# differential_evolution step 23: f(x)= 757.7690570877016
# differential_evolution step 24: f(x)= 757.7690570877016
# differential_evolution step 25: f(x)= 757.7690570877016
# differential_evolution step 26: f(x)= 757.7690570877016
# differential_evolution step 27: f(x)= 701.4947058892403
# differential_evolution step 28: f(x)= 701.4947058892403
# differential_evolution step 29: f(x)= 701.4947058892403
# differential_evolution step 30: f(x)= 689.3895870803339
# differential_evolution step 31: f(x)= 689.3895870803339
# differential_evolution step 32: f(x)= 689.3895870803339
# differential_evolution step 33: f(x)= 689.3895870803339
# differential_evolution step 34: f(x)= 689.3895870803339
# differential_evolution step 35: f(x)= 689.3895870803339
# differential_evolution step 36: f(x)= 689.3895870803339
# differential_evolution step 37: f(x)= 635.1180509845622
# differential_evolution step 38: f(x)= 568.7808535479859
# differential_evolution step 39: f(x)= 568.7808535479859
# differential_evolution step 40: f(x)= 568.7808535479859
# differential_evolution step 41: f(x)= 568.7808535479859
# differential_evolution step 42: f(x)= 568.7808535479859
# differential_evolution step 43: f(x)= 535.4510565771831
# differential_evolution step 44: f(x)= 471.33593821867055
# differential_evolution step 45: f(x)= 471.33593821867055
# differential_evolution step 46: f(x)= 471.33593821867055
# differential_evolution step 47: f(x)= 471.33593821867055
# differential_evolution step 48: f(x)= 471.33593821867055
# differential_evolution step 49: f(x)= 471.33593821867055
# differential_evolution step 50: f(x)= 467.5532572927374
# differential_evolution step 51: f(x)= 467.5532572927374
# differential_evolution step 52: f(x)= 467.5532572927374
# differential_evolution step 53: f(x)= 467.5532572927374
# differential_evolution step 54: f(x)= 427.04614051976
# differential_evolution step 55: f(x)= 427.04614051976
# differential_evolution step 56: f(x)= 427.04614051976
# differential_evolution step 57: f(x)= 427.04614051976
# differential_evolution step 58: f(x)= 427.04614051976
# differential_evolution step 59: f(x)= 427.04614051976
# differential_evolution step 60: f(x)= 427.04614051976
# differential_evolution step 61: f(x)= 393.0923806690312
# differential_evolution step 62: f(x)= 374.44707476399844
# differential_evolution step 63: f(x)= 374.44707476399844
# differential_evolution step 64: f(x)= 374.44707476399844
# differential_evolution step 65: f(x)= 374.44707476399844
# differential_evolution step 66: f(x)= 374.44707476399844
# differential_evolution step 67: f(x)= 360.8221240144553
# differential_evolution step 68: f(x)= 360.8221240144553
# differential_evolution step 69: f(x)= 360.8221240144553
# differential_evolution step 70: f(x)= 360.8221240144553
# differential_evolution step 71: f(x)= 360.8221240144553
# differential_evolution step 72: f(x)= 322.10699628136734
# differential_evolution step 73: f(x)= 322.10699628136734
# differential_evolution step 74: f(x)= 322.10699628136734
# differential_evolution step 75: f(x)= 313.56826808583105
# differential_evolution step 76: f(x)= 313.56826808583105
# differential_evolution step 77: f(x)= 313.56826808583105
# differential_evolution step 78: f(x)= 313.56826808583105
# differential_evolution step 79: f(x)= 289.3592188184097
# differential_evolution step 80: f(x)= 274.6333309081534
# differential_evolution step 81: f(x)= 274.6333309081534
# differential_evolution step 82: f(x)= 267.99355060550823
# differential_evolution step 83: f(x)= 267.99355060550823
# differential_evolution step 84: f(x)= 267.99355060550823
# differential_evolution step 85: f(x)= 257.313583729695
# differential_evolution step 86: f(x)= 257.313583729695
# differential_evolution step 87: f(x)= 257.313583729695
# differential_evolution step 88: f(x)= 249.28011303246464
# differential_evolution step 89: f(x)= 249.28011303246464
# differential_evolution step 90: f(x)= 249.28011303246464
# differential_evolution step 91: f(x)= 249.28011303246464
# differential_evolution step 92: f(x)= 249.28011303246464
# differential_evolution step 93: f(x)= 249.28011303246464
# differential_evolution step 94: f(x)= 249.28011303246464
# differential_evolution step 95: f(x)= 228.25103035814334
# differential_evolution step 96: f(x)= 228.25103035814334
# differential_evolution step 97: f(x)= 223.08148046458217
# differential_evolution step 98: f(x)= 223.08148046458217
# differential_evolution step 99: f(x)= 216.68662253268144
# differential_evolution step 100: f(x)= 216.68662253268144
# differential_evolution step 101: f(x)= 216.68662253268144
# differential_evolution step 102: f(x)= 216.68662253268144
# differential_evolution step 103: f(x)= 216.68662253268144
# differential_evolution step 104: f(x)= 216.68662253268144
# differential_evolution step 105: f(x)= 207.94837837483686
# differential_evolution step 106: f(x)= 205.31529789807112
# differential_evolution step 107: f(x)= 198.27138098171832
# differential_evolution step 108: f(x)= 198.27138098171832
# differential_evolution step 109: f(x)= 198.27138098171832
# differential_evolution step 110: f(x)= 197.09884751872826
# differential_evolution step 111: f(x)= 197.09884751872826
# differential_evolution step 112: f(x)= 197.09884751872826
# differential_evolution step 113: f(x)= 193.7244365217987
# differential_evolution step 114: f(x)= 190.33968966385996
# differential_evolution step 115: f(x)= 187.26499500595594
# differential_evolution step 116: f(x)= 185.66318838714867
# differential_evolution step 117: f(x)= 184.80759164742452
# differential_evolution step 118: f(x)= 184.80759164742452
# differential_evolution step 119: f(x)= 184.80759164742452
# differential_evolution step 120: f(x)= 184.80759164742452
# differential_evolution step 121: f(x)= 184.80759164742452
# differential_evolution step 122: f(x)= 182.10992822777547
# differential_evolution step 123: f(x)= 182.10992822777547
# differential_evolution step 124: f(x)= 182.10992822777547
# differential_evolution step 125: f(x)= 182.10992822777547
# differential_evolution step 126: f(x)= 182.10992822777547
# differential_evolution step 127: f(x)= 181.92629735252476
# differential_evolution step 128: f(x)= 181.2964616883942
# differential_evolution step 129: f(x)= 178.69005388493886
# differential_evolution step 130: f(x)= 178.69005388493886
# differential_evolution step 131: f(x)= 178.69005388493886
# differential_evolution step 132: f(x)= 178.69005388493886
# differential_evolution step 133: f(x)= 178.69005388493886
# differential_evolution step 134: f(x)= 178.34401796010525
# differential_evolution step 135: f(x)= 178.24204150566288
# differential_evolution step 136: f(x)= 178.24204150566288
# differential_evolution step 137: f(x)= 178.24204150566288
# differential_evolution step 138: f(x)= 178.24204150566288
# differential_evolution step 139: f(x)= 178.24204150566288
# differential_evolution step 140: f(x)= 178.24204150566288
# differential_evolution step 141: f(x)= 178.07514940225553
# differential_evolution step 142: f(x)= 178.07514940225553
# differential_evolution step 143: f(x)= 176.31285266269285
# differential_evolution step 144: f(x)= 176.31285266269285
# differential_evolution step 145: f(x)= 176.31285266269285
# differential_evolution step 146: f(x)= 176.31285266269285
# differential_evolution step 147: f(x)= 176.31285266269285
# differential_evolution step 148: f(x)= 176.31285266269285
# differential_evolution step 149: f(x)= 176.31285266269285
# differential_evolution step 150: f(x)= 176.31285266269285
# differential_evolution step 151: f(x)= 176.31285266269285
# differential_evolution step 152: f(x)= 176.31285266269285
# differential_evolution step 153: f(x)= 176.04769195304848
# differential_evolution step 154: f(x)= 176.04769195304848
# differential_evolution step 155: f(x)= 176.04769195304848
# differential_evolution step 156: f(x)= 176.04769195304848
# differential_evolution step 157: f(x)= 176.04769195304848
# differential_evolution step 158: f(x)= 175.36526990776684
# differential_evolution step 159: f(x)= 175.36526990776684
# differential_evolution step 160: f(x)= 175.36526990776684
# differential_evolution step 161: f(x)= 175.36526990776684
# differential_evolution step 162: f(x)= 175.36526990776684
# differential_evolution step 163: f(x)= 175.36526990776684
# differential_evolution step 164: f(x)= 174.80803999472627
# differential_evolution step 165: f(x)= 174.80803999472627
# differential_evolution step 166: f(x)= 174.80803999472627
# differential_evolution step 167: f(x)= 174.80803999472627
# differential_evolution step 168: f(x)= 174.80803999472627
# differential_evolution step 169: f(x)= 174.80803999472627
# differential_evolution step 170: f(x)= 174.6461034478921
# differential_evolution step 171: f(x)= 174.6461034478921
# differential_evolution step 172: f(x)= 174.6461034478921
# differential_evolution step 173: f(x)= 174.6461034478921
# differential_evolution step 174: f(x)= 174.6461034478921
# differential_evolution step 175: f(x)= 174.51445619107085
# differential_evolution step 176: f(x)= 174.51445619107085
# differential_evolution step 177: f(x)= 174.45109755363077
# differential_evolution step 178: f(x)= 174.45109755363077
# differential_evolution step 179: f(x)= 174.24619333840613
# differential_evolution step 180: f(x)= 174.24619333840613
# differential_evolution step 181: f(x)= 174.24619333840613
# differential_evolution step 182: f(x)= 174.23694084927737
# differential_evolution step 183: f(x)= 174.23694084927737
# differential_evolution step 184: f(x)= 174.23694084927737
# differential_evolution step 185: f(x)= 174.23694084927737
# differential_evolution step 186: f(x)= 174.23694084927737
# differential_evolution step 187: f(x)= 174.23694084927737
# differential_evolution step 188: f(x)= 174.23694084927737
# differential_evolution step 189: f(x)= 174.23694084927737
# differential_evolution step 190: f(x)= 174.23694084927737
# differential_evolution step 191: f(x)= 174.23694084927737
# differential_evolution step 192: f(x)= 174.23694084927737
# differential_evolution step 193: f(x)= 174.23694084927737
# differential_evolution step 194: f(x)= 174.23694084927737
# differential_evolution step 195: f(x)= 174.23694084927737
# differential_evolution step 196: f(x)= 174.178092692871
# differential_evolution step 197: f(x)= 174.16068874845794
# differential_evolution step 198: f(x)= 174.16068874845794
# differential_evolution step 199: f(x)= 174.16068874845794
# differential_evolution step 200: f(x)= 174.16068874845794
# differential_evolution step 201: f(x)= 174.12406863023133
# differential_evolution step 202: f(x)= 174.12406863023133
# differential_evolution step 203: f(x)= 174.12406863023133
# differential_evolution step 204: f(x)= 174.12406863023133
# differential_evolution step 205: f(x)= 174.12379707734613
# differential_evolution step 206: f(x)= 174.1088073975548
# differential_evolution step 207: f(x)= 174.09791377757904
# differential_evolution step 208: f(x)= 174.09791377757904
# differential_evolution step 209: f(x)= 174.09652244110873
# differential_evolution step 210: f(x)= 174.09192261069828
# differential_evolution step 211: f(x)= 174.0750507253797
# differential_evolution step 212: f(x)= 174.0750507253797
# differential_evolution step 213: f(x)= 174.0750507253797
# differential_evolution step 214: f(x)= 174.07283962884154
# differential_evolution step 215: f(x)= 174.07283962884154
# differential_evolution step 216: f(x)= 174.06614082164143
# differential_evolution step 217: f(x)= 174.0622073925252
# differential_evolution step 218: f(x)= 174.0607862566114
# differential_evolution step 219: f(x)= 174.0607862566114
# differential_evolution step 220: f(x)= 174.0607862566114
# differential_evolution step 221: f(x)= 174.0607862566114
# differential_evolution step 222: f(x)= 174.0607862566114
# differential_evolution step 223: f(x)= 174.0607862566114
# differential_evolution step 224: f(x)= 174.0607862566114
# differential_evolution step 225: f(x)= 174.0607862566114
# differential_evolution step 226: f(x)= 174.0607862566114
# differential_evolution step 227: f(x)= 174.0535121894715
# differential_evolution step 228: f(x)= 174.04914540101993
# differential_evolution step 229: f(x)= 174.04914540101993
# differential_evolution step 230: f(x)= 174.04914540101993
# differential_evolution step 231: f(x)= 174.04914540101993
# differential_evolution step 232: f(x)= 174.04914540101993
# differential_evolution step 233: f(x)= 174.04682251679532
# differential_evolution step 234: f(x)= 174.04665413882654
# differential_evolution step 235: f(x)= 174.04665413882654
# differential_evolution step 236: f(x)= 174.04665413882654
# differential_evolution step 237: f(x)= 174.04424418159198
# differential_evolution step 238: f(x)= 174.04424418159198
# differential_evolution step 239: f(x)= 174.04277311339365
# differential_evolution step 240: f(x)= 174.04277311339365
# differential_evolution step 241: f(x)= 174.04277311339365
# differential_evolution step 242: f(x)= 174.04277311339365
# differential_evolution step 243: f(x)= 174.04277311339365
# differential_evolution step 244: f(x)= 174.04226651282698
# differential_evolution step 245: f(x)= 174.04226651282698
# differential_evolution step 246: f(x)= 174.04226651282698
# differential_evolution step 247: f(x)= 174.0421381682788
# differential_evolution step 248: f(x)= 174.0421381682788
# differential_evolution step 249: f(x)= 174.04131554669092
# differential_evolution step 250: f(x)= 174.04131554669092
# differential_evolution step 251: f(x)= 174.04131554669092
# differential_evolution step 252: f(x)= 174.04073856014546
# differential_evolution step 253: f(x)= 174.04073856014546
# differential_evolution step 254: f(x)= 174.04073856014546
# differential_evolution step 255: f(x)= 174.04053743091913
# differential_evolution step 256: f(x)= 174.04053743091913
# differential_evolution step 257: f(x)= 174.04053743091913
# differential_evolution step 258: f(x)= 174.04021377315598
# differential_evolution step 259: f(x)= 174.04021377315598
# differential_evolution step 260: f(x)= 174.0384334152926
# differential_evolution step 261: f(x)= 174.0384334152926
# differential_evolution step 262: f(x)= 174.0384334152926
# differential_evolution step 263: f(x)= 174.0384334152926
# differential_evolution step 264: f(x)= 174.0384334152926
# differential_evolution step 265: f(x)= 174.0384334152926
# differential_evolution step 266: f(x)= 174.0384334152926
# differential_evolution step 267: f(x)= 174.0384334152926
# differential_evolution step 268: f(x)= 174.0384334152926
# differential_evolution step 269: f(x)= 174.0384334152926
# differential_evolution step 270: f(x)= 174.0384334152926
# differential_evolution step 271: f(x)= 174.0384334152926
# differential_evolution step 272: f(x)= 174.038386793174
# differential_evolution step 273: f(x)= 174.038386793174
# differential_evolution step 274: f(x)= 174.0383167400198
# differential_evolution step 275: f(x)= 174.0383167400198
# differential_evolution step 276: f(x)= 174.03794375909632
# differential_evolution step 277: f(x)= 174.03794375909632
# differential_evolution step 278: f(x)= 174.03794375909632
# differential_evolution step 279: f(x)= 174.03794375909632
# differential_evolution step 280: f(x)= 174.03794375909632
# differential_evolution step 281: f(x)= 174.03793698443553
# differential_evolution step 282: f(x)= 174.03793698443553
# differential_evolution step 283: f(x)= 174.0378997815852
# differential_evolution step 284: f(x)= 174.0378997815852
# differential_evolution step 285: f(x)= 174.03785506152312
# differential_evolution step 286: f(x)= 174.03785506152312
# differential_evolution step 287: f(x)= 174.03780818805706
# differential_evolution step 288: f(x)= 174.03780818805706
# differential_evolution step 289: f(x)= 174.03780818805706
# differential_evolution step 290: f(x)= 174.03775286175812
# differential_evolution step 291: f(x)= 174.03775286175812
# differential_evolution step 292: f(x)= 174.03775286175812
# differential_evolution step 293: f(x)= 174.03775286175812
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 1.84713773 25.84626651  1.99690906 51.49287322 19.9999893   3.69365847
#   0.65941948 61.03085374]
# Chi quadro minimo: 174.03775286175812

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=4.0860, r_e=14.6505, n=1.3869, x_0=51.1958
# Sérsic 2: I_e=16.1360, r_e=4.3053, n=0.7948, x_0=61.1590
# [0.33828588 0.56130643 0.06398281 0.15322997 1.35407153 0.22187086
#  0.06111084 0.0930601 ]
# 277.8693623115806
# 295.45177989399815 277.8693623115806 314.7107237994853 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (0, 100),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 29870.419048472457
# differential_evolution step 2: f(x)= 9102.67143743432
# differential_evolution step 3: f(x)= 9102.67143743432
# differential_evolution step 4: f(x)= 9102.67143743432
# differential_evolution step 5: f(x)= 9102.67143743432
# differential_evolution step 6: f(x)= 5666.487691142701
# differential_evolution step 7: f(x)= 5666.487691142701
# differential_evolution step 8: f(x)= 4200.339086702256
# differential_evolution step 9: f(x)= 4068.0270557734502
# differential_evolution step 10: f(x)= 3866.7668164908346
# differential_evolution step 11: f(x)= 2282.182030974937
# differential_evolution step 12: f(x)= 2282.182030974937
# differential_evolution step 13: f(x)= 2282.182030974937
# differential_evolution step 14: f(x)= 2282.182030974937
# differential_evolution step 15: f(x)= 2282.182030974937
# differential_evolution step 16: f(x)= 2282.182030974937
# differential_evolution step 17: f(x)= 2203.803187290301
# differential_evolution step 18: f(x)= 2203.803187290301
# differential_evolution step 19: f(x)= 2203.803187290301
# differential_evolution step 20: f(x)= 1676.852462220753
# differential_evolution step 21: f(x)= 1676.852462220753
# differential_evolution step 22: f(x)= 1098.9396837492436
# differential_evolution step 23: f(x)= 1098.9396837492436
# differential_evolution step 24: f(x)= 1098.9396837492436
# differential_evolution step 25: f(x)= 1098.9396837492436
# differential_evolution step 26: f(x)= 1098.9396837492436
# differential_evolution step 27: f(x)= 1098.9396837492436
# differential_evolution step 28: f(x)= 1098.9396837492436
# differential_evolution step 29: f(x)= 786.0390376726837
# differential_evolution step 30: f(x)= 786.0390376726837
# differential_evolution step 31: f(x)= 786.0390376726837
# differential_evolution step 32: f(x)= 786.0390376726837
# differential_evolution step 33: f(x)= 786.0390376726837
# differential_evolution step 34: f(x)= 786.0390376726837
# differential_evolution step 35: f(x)= 786.0390376726837
# differential_evolution step 36: f(x)= 786.0390376726837
# differential_evolution step 37: f(x)= 786.0390376726837
# differential_evolution step 38: f(x)= 570.5618024539117
# differential_evolution step 39: f(x)= 570.5618024539117
# differential_evolution step 40: f(x)= 570.5618024539117
# differential_evolution step 41: f(x)= 570.5618024539117
# differential_evolution step 42: f(x)= 570.5618024539117
# differential_evolution step 43: f(x)= 570.5618024539117
# differential_evolution step 44: f(x)= 570.5618024539117
# differential_evolution step 45: f(x)= 570.5618024539117
# differential_evolution step 46: f(x)= 570.5618024539117
# differential_evolution step 47: f(x)= 570.5618024539117
# differential_evolution step 48: f(x)= 570.5618024539117
# differential_evolution step 49: f(x)= 570.5618024539117
# differential_evolution step 50: f(x)= 570.5618024539117
# differential_evolution step 51: f(x)= 559.8825208333872
# differential_evolution step 52: f(x)= 559.8825208333872
# differential_evolution step 53: f(x)= 559.8825208333872
# differential_evolution step 54: f(x)= 559.8825208333872
# differential_evolution step 55: f(x)= 559.8825208333872
# differential_evolution step 56: f(x)= 559.8825208333872
# differential_evolution step 57: f(x)= 559.8825208333872
# differential_evolution step 58: f(x)= 559.8825208333872
# differential_evolution step 59: f(x)= 559.8825208333872
# differential_evolution step 60: f(x)= 559.8825208333872
# differential_evolution step 61: f(x)= 559.8825208333872
# differential_evolution step 62: f(x)= 543.5415631184367
# differential_evolution step 63: f(x)= 543.5415631184367
# differential_evolution step 64: f(x)= 543.5415631184367
# differential_evolution step 65: f(x)= 543.5415631184367
# differential_evolution step 66: f(x)= 507.10912958632355
# differential_evolution step 67: f(x)= 507.10912958632355
# differential_evolution step 68: f(x)= 507.10912958632355
# differential_evolution step 69: f(x)= 483.9105856510379
# differential_evolution step 70: f(x)= 483.9105856510379
# differential_evolution step 71: f(x)= 483.9105856510379
# differential_evolution step 72: f(x)= 483.9105856510379
# differential_evolution step 73: f(x)= 483.9105856510379
# differential_evolution step 74: f(x)= 482.19690442933756
# differential_evolution step 75: f(x)= 479.8224059118628
# differential_evolution step 76: f(x)= 477.4844878276258
# differential_evolution step 77: f(x)= 477.4844878276258
# differential_evolution step 78: f(x)= 477.4844878276258
# differential_evolution step 79: f(x)= 477.4844878276258
# differential_evolution step 80: f(x)= 425.5273783870971
# differential_evolution step 81: f(x)= 425.5273783870971
# differential_evolution step 82: f(x)= 425.5273783870971
# differential_evolution step 83: f(x)= 425.5273783870971
# differential_evolution step 84: f(x)= 425.5273783870971
# differential_evolution step 85: f(x)= 415.7470262151508
# differential_evolution step 86: f(x)= 415.7470262151508
# differential_evolution step 87: f(x)= 415.7470262151508
# differential_evolution step 88: f(x)= 415.7470262151508
# differential_evolution step 89: f(x)= 415.7470262151508
# differential_evolution step 90: f(x)= 415.7470262151508
# differential_evolution step 91: f(x)= 409.0403250420508
# differential_evolution step 92: f(x)= 409.0403250420508
# differential_evolution step 93: f(x)= 409.0403250420508
# differential_evolution step 94: f(x)= 409.0403250420508
# differential_evolution step 95: f(x)= 385.16342445361704
# differential_evolution step 96: f(x)= 385.16342445361704
# differential_evolution step 97: f(x)= 362.1153418504519
# differential_evolution step 98: f(x)= 362.1153418504519
# differential_evolution step 99: f(x)= 362.1153418504519
# differential_evolution step 100: f(x)= 362.1153418504519
# differential_evolution step 101: f(x)= 362.1153418504519
# differential_evolution step 102: f(x)= 357.19328231221505
# differential_evolution step 103: f(x)= 343.1069823529663
# differential_evolution step 104: f(x)= 343.1069823529663
# differential_evolution step 105: f(x)= 343.1069823529663
# differential_evolution step 106: f(x)= 343.1069823529663
# differential_evolution step 107: f(x)= 343.1069823529663
# differential_evolution step 108: f(x)= 343.1069823529663
# differential_evolution step 109: f(x)= 343.1069823529663
# differential_evolution step 110: f(x)= 343.1069823529663
# differential_evolution step 111: f(x)= 343.1069823529663
# differential_evolution step 112: f(x)= 343.1069823529663
# differential_evolution step 113: f(x)= 343.1069823529663
# differential_evolution step 114: f(x)= 337.5368943180861
# differential_evolution step 115: f(x)= 337.5368943180861
# differential_evolution step 116: f(x)= 325.8080513117068
# differential_evolution step 117: f(x)= 325.8080513117068
# differential_evolution step 118: f(x)= 325.8080513117068
# differential_evolution step 119: f(x)= 325.76825793457726
# differential_evolution step 120: f(x)= 325.76825793457726
# differential_evolution step 121: f(x)= 325.76825793457726
# differential_evolution step 122: f(x)= 325.76825793457726
# differential_evolution step 123: f(x)= 325.76825793457726
# differential_evolution step 124: f(x)= 325.76825793457726
# differential_evolution step 125: f(x)= 321.59341971154095
# differential_evolution step 126: f(x)= 321.59341971154095
# differential_evolution step 127: f(x)= 321.59341971154095
# differential_evolution step 128: f(x)= 274.9163252111191
# differential_evolution step 129: f(x)= 274.9163252111191
# differential_evolution step 130: f(x)= 274.9163252111191
# differential_evolution step 131: f(x)= 274.9163252111191
# differential_evolution step 132: f(x)= 274.9163252111191
# differential_evolution step 133: f(x)= 274.9163252111191
# differential_evolution step 134: f(x)= 249.66311180929227
# differential_evolution step 135: f(x)= 249.66311180929227
# differential_evolution step 136: f(x)= 249.66311180929227
# differential_evolution step 137: f(x)= 249.66311180929227
# differential_evolution step 138: f(x)= 249.66311180929227
# differential_evolution step 139: f(x)= 237.16719478242095
# differential_evolution step 140: f(x)= 237.16719478242095
# differential_evolution step 141: f(x)= 237.16719478242095
# differential_evolution step 142: f(x)= 237.16719478242095
# differential_evolution step 143: f(x)= 217.24941002684935
# differential_evolution step 144: f(x)= 217.24941002684935
# differential_evolution step 145: f(x)= 217.24941002684935
# differential_evolution step 146: f(x)= 217.24941002684935
# differential_evolution step 147: f(x)= 217.24941002684935
# differential_evolution step 148: f(x)= 217.24941002684935
# differential_evolution step 149: f(x)= 217.24941002684935
# differential_evolution step 150: f(x)= 217.24941002684935
# differential_evolution step 151: f(x)= 217.24941002684935
# differential_evolution step 152: f(x)= 217.24941002684935
# differential_evolution step 153: f(x)= 217.24941002684935
# differential_evolution step 154: f(x)= 217.24941002684935
# differential_evolution step 155: f(x)= 217.24941002684935
# differential_evolution step 156: f(x)= 217.24941002684935
# differential_evolution step 157: f(x)= 217.09246795681386
# differential_evolution step 158: f(x)= 205.4075712522436
# differential_evolution step 159: f(x)= 205.4075712522436
# differential_evolution step 160: f(x)= 205.4075712522436
# differential_evolution step 161: f(x)= 205.4075712522436
# differential_evolution step 162: f(x)= 205.4075712522436
# differential_evolution step 163: f(x)= 205.4075712522436
# differential_evolution step 164: f(x)= 205.4075712522436
# differential_evolution step 165: f(x)= 205.4075712522436
# differential_evolution step 166: f(x)= 205.4075712522436
# differential_evolution step 167: f(x)= 205.4075712522436
# differential_evolution step 168: f(x)= 205.4075712522436
# differential_evolution step 169: f(x)= 203.88288826024308
# differential_evolution step 170: f(x)= 203.88288826024308
# differential_evolution step 171: f(x)= 203.88288826024308
# differential_evolution step 172: f(x)= 203.88288826024308
# differential_evolution step 173: f(x)= 203.88288826024308
# differential_evolution step 174: f(x)= 203.88288826024308
# differential_evolution step 175: f(x)= 203.88288826024308
# differential_evolution step 176: f(x)= 203.88288826024308
# differential_evolution step 177: f(x)= 203.88288826024308
# differential_evolution step 178: f(x)= 203.88288826024308
# differential_evolution step 179: f(x)= 203.88288826024308
# differential_evolution step 180: f(x)= 203.88288826024308
# differential_evolution step 181: f(x)= 203.88288826024308
# differential_evolution step 182: f(x)= 203.88288826024308
# differential_evolution step 183: f(x)= 203.88288826024308
# differential_evolution step 184: f(x)= 203.24063895221403
# differential_evolution step 185: f(x)= 190.78969943000038
# differential_evolution step 186: f(x)= 167.86847267380827
# differential_evolution step 187: f(x)= 167.58136261872568
# differential_evolution step 188: f(x)= 167.58136261872568
# differential_evolution step 189: f(x)= 167.58136261872568
# differential_evolution step 190: f(x)= 167.58136261872568
# differential_evolution step 191: f(x)= 164.74227475770772
# differential_evolution step 192: f(x)= 164.73188681892188
# differential_evolution step 193: f(x)= 164.73188681892188
# differential_evolution step 194: f(x)= 161.05246246680792
# differential_evolution step 195: f(x)= 161.05246246680792
# differential_evolution step 196: f(x)= 161.05246246680792
# differential_evolution step 197: f(x)= 161.05246246680792
# differential_evolution step 198: f(x)= 161.05246246680792
# differential_evolution step 199: f(x)= 161.05246246680792
# differential_evolution step 200: f(x)= 144.46484639564034
# differential_evolution step 201: f(x)= 144.46484639564034
# differential_evolution step 202: f(x)= 144.46484639564034
# differential_evolution step 203: f(x)= 140.1327553678637
# differential_evolution step 204: f(x)= 140.1327553678637
# differential_evolution step 205: f(x)= 140.1327553678637
# differential_evolution step 206: f(x)= 140.1327553678637
# differential_evolution step 207: f(x)= 140.1327553678637
# differential_evolution step 208: f(x)= 140.1327553678637
# differential_evolution step 209: f(x)= 140.1327553678637
# differential_evolution step 210: f(x)= 123.12281072724385
# differential_evolution step 211: f(x)= 123.12281072724385
# differential_evolution step 212: f(x)= 123.12281072724385
# differential_evolution step 213: f(x)= 123.12281072724385
# differential_evolution step 214: f(x)= 123.12281072724385
# differential_evolution step 215: f(x)= 123.12281072724385
# differential_evolution step 216: f(x)= 123.12281072724385
# differential_evolution step 217: f(x)= 123.12281072724385
# differential_evolution step 218: f(x)= 123.12281072724385
# differential_evolution step 219: f(x)= 97.45143905391781
# differential_evolution step 220: f(x)= 97.45143905391781
# differential_evolution step 221: f(x)= 97.45143905391781
# differential_evolution step 222: f(x)= 97.45143905391781
# differential_evolution step 223: f(x)= 97.45143905391781
# differential_evolution step 224: f(x)= 97.45143905391781
# differential_evolution step 225: f(x)= 97.45143905391781
# differential_evolution step 226: f(x)= 97.45143905391781
# differential_evolution step 227: f(x)= 97.45143905391781
# differential_evolution step 228: f(x)= 97.45143905391781
# differential_evolution step 229: f(x)= 97.45143905391781
# differential_evolution step 230: f(x)= 97.45143905391781
# differential_evolution step 231: f(x)= 97.45143905391781
# differential_evolution step 232: f(x)= 97.45143905391781
# differential_evolution step 233: f(x)= 97.45143905391781
# differential_evolution step 234: f(x)= 97.45143905391781
# differential_evolution step 235: f(x)= 97.45143905391781
# differential_evolution step 236: f(x)= 97.45143905391781
# differential_evolution step 237: f(x)= 97.45143905391781
# differential_evolution step 238: f(x)= 97.45143905391781
# differential_evolution step 239: f(x)= 97.45143905391781
# differential_evolution step 240: f(x)= 97.45143905391781
# differential_evolution step 241: f(x)= 97.45143905391781
# differential_evolution step 242: f(x)= 97.45143905391781
# differential_evolution step 243: f(x)= 96.67254002370431
# differential_evolution step 244: f(x)= 96.67254002370431
# differential_evolution step 245: f(x)= 94.02338439371448
# differential_evolution step 246: f(x)= 94.02338439371448
# differential_evolution step 247: f(x)= 94.02338439371448
# differential_evolution step 248: f(x)= 94.02338439371448
# differential_evolution step 249: f(x)= 94.02338439371448
# differential_evolution step 250: f(x)= 94.02338439371448
# differential_evolution step 251: f(x)= 94.02338439371448
# differential_evolution step 252: f(x)= 94.02338439371448
# differential_evolution step 253: f(x)= 94.02338439371448
# differential_evolution step 254: f(x)= 94.02338439371448
# differential_evolution step 255: f(x)= 94.02338439371448
# differential_evolution step 256: f(x)= 94.02338439371448
# differential_evolution step 257: f(x)= 94.02338439371448
# differential_evolution step 258: f(x)= 94.02338439371448
# differential_evolution step 259: f(x)= 94.02338439371448
# differential_evolution step 260: f(x)= 94.02338439371448
# differential_evolution step 261: f(x)= 90.12158762342662
# differential_evolution step 262: f(x)= 90.12158762342662
# differential_evolution step 263: f(x)= 84.39334215544957
# differential_evolution step 264: f(x)= 84.39334215544957
# differential_evolution step 265: f(x)= 84.39334215544957
# differential_evolution step 266: f(x)= 84.39334215544957
# differential_evolution step 267: f(x)= 84.39334215544957
# differential_evolution step 268: f(x)= 84.39334215544957
# differential_evolution step 269: f(x)= 84.39334215544957
# differential_evolution step 270: f(x)= 84.39334215544957
# differential_evolution step 271: f(x)= 84.39334215544957
# differential_evolution step 272: f(x)= 84.39334215544957
# differential_evolution step 273: f(x)= 84.39334215544957
# differential_evolution step 274: f(x)= 84.39334215544957
# differential_evolution step 275: f(x)= 84.39334215544957
# differential_evolution step 276: f(x)= 84.39334215544957
# differential_evolution step 277: f(x)= 84.39334215544957
# differential_evolution step 278: f(x)= 84.39334215544957
# differential_evolution step 279: f(x)= 84.39334215544957
# differential_evolution step 280: f(x)= 83.60417348406467
# differential_evolution step 281: f(x)= 83.60417348406467
# differential_evolution step 282: f(x)= 83.60417348406467
# differential_evolution step 283: f(x)= 83.60417348406467
# differential_evolution step 284: f(x)= 83.60417348406467
# differential_evolution step 285: f(x)= 82.08138879723779
# differential_evolution step 286: f(x)= 82.08138879723779
# differential_evolution step 287: f(x)= 82.08138879723779
# differential_evolution step 288: f(x)= 82.08138879723779
# differential_evolution step 289: f(x)= 82.08138879723779
# differential_evolution step 290: f(x)= 82.08138879723779
# differential_evolution step 291: f(x)= 81.42663057449458
# differential_evolution step 292: f(x)= 81.42663057449458
# differential_evolution step 293: f(x)= 81.42663057449458
# differential_evolution step 294: f(x)= 81.42663057449458
# differential_evolution step 295: f(x)= 80.84092951445483
# differential_evolution step 296: f(x)= 80.84092951445483
# differential_evolution step 297: f(x)= 80.84092951445483
# differential_evolution step 298: f(x)= 80.84092951445483
# differential_evolution step 299: f(x)= 80.84092951445483
# differential_evolution step 300: f(x)= 80.84092951445483
# differential_evolution step 301: f(x)= 80.84092951445483
# differential_evolution step 302: f(x)= 80.84092951445483
# differential_evolution step 303: f(x)= 80.84092951445483
# differential_evolution step 304: f(x)= 80.84092951445483
# differential_evolution step 305: f(x)= 80.84092951445483
# differential_evolution step 306: f(x)= 80.84092951445483
# differential_evolution step 307: f(x)= 80.84092951445483
# differential_evolution step 308: f(x)= 80.84092951445483
# differential_evolution step 309: f(x)= 80.84092951445483
# differential_evolution step 310: f(x)= 80.84092951445483
# differential_evolution step 311: f(x)= 80.84092951445483
# differential_evolution step 312: f(x)= 80.84092951445483
# differential_evolution step 313: f(x)= 80.84092951445483
# differential_evolution step 314: f(x)= 80.84092951445483
# differential_evolution step 315: f(x)= 80.84092951445483
# differential_evolution step 316: f(x)= 80.70226978579667
# differential_evolution step 317: f(x)= 79.78769721471504
# differential_evolution step 318: f(x)= 79.78769721471504
# differential_evolution step 319: f(x)= 79.78769721471504
# differential_evolution step 320: f(x)= 79.78769721471504
# differential_evolution step 321: f(x)= 79.78769721471504
# differential_evolution step 322: f(x)= 79.78769721471504
# differential_evolution step 323: f(x)= 79.78769721471504
# differential_evolution step 324: f(x)= 79.78769721471504
# differential_evolution step 325: f(x)= 79.78769721471504
# differential_evolution step 326: f(x)= 79.78769721471504
# differential_evolution step 327: f(x)= 79.78769721471504
# differential_evolution step 328: f(x)= 79.78769721471504
# differential_evolution step 329: f(x)= 79.78769721471504
# differential_evolution step 330: f(x)= 79.78769721471504
# differential_evolution step 331: f(x)= 79.78769721471504
# differential_evolution step 332: f(x)= 79.78769721471504
# differential_evolution step 333: f(x)= 79.4128480426231
# differential_evolution step 334: f(x)= 79.4128480426231
# differential_evolution step 335: f(x)= 79.4128480426231
# differential_evolution step 336: f(x)= 79.4128480426231
# differential_evolution step 337: f(x)= 79.4128480426231
# differential_evolution step 338: f(x)= 79.4128480426231
# differential_evolution step 339: f(x)= 79.4128480426231
# differential_evolution step 340: f(x)= 79.4128480426231
# differential_evolution step 341: f(x)= 79.4128480426231
# differential_evolution step 342: f(x)= 79.4128480426231
# differential_evolution step 343: f(x)= 79.21423312755162
# differential_evolution step 344: f(x)= 79.21423312755162
# differential_evolution step 345: f(x)= 79.21423312755162
# differential_evolution step 346: f(x)= 79.17003827556822
# differential_evolution step 347: f(x)= 79.17003827556822
# differential_evolution step 348: f(x)= 79.17003827556822
# differential_evolution step 349: f(x)= 79.15802760723173
# differential_evolution step 350: f(x)= 79.12500723979475
# differential_evolution step 351: f(x)= 79.12500723979475
# differential_evolution step 352: f(x)= 78.79809702423888
# differential_evolution step 353: f(x)= 78.04044667978314
# differential_evolution step 354: f(x)= 78.04044667978314
# differential_evolution step 355: f(x)= 77.47504174529129
# differential_evolution step 356: f(x)= 77.47504174529129
# differential_evolution step 357: f(x)= 77.47504174529129
# differential_evolution step 358: f(x)= 77.47504174529129
# differential_evolution step 359: f(x)= 77.47504174529129
# differential_evolution step 360: f(x)= 77.47504174529129
# differential_evolution step 361: f(x)= 77.47504174529129
# differential_evolution step 362: f(x)= 77.47504174529129
# differential_evolution step 363: f(x)= 77.47504174529129
# differential_evolution step 364: f(x)= 77.47504174529129
# differential_evolution step 365: f(x)= 77.47504174529129
# differential_evolution step 366: f(x)= 77.47504174529129
# differential_evolution step 367: f(x)= 77.47504174529129
# differential_evolution step 368: f(x)= 77.47504174529129
# differential_evolution step 369: f(x)= 77.47504174529129
# differential_evolution step 370: f(x)= 77.47504174529129
# differential_evolution step 371: f(x)= 77.47504174529129
# differential_evolution step 372: f(x)= 77.47504174529129
# differential_evolution step 373: f(x)= 77.47504174529129
# differential_evolution step 374: f(x)= 77.47504174529129
# differential_evolution step 375: f(x)= 77.47504174529129
# differential_evolution step 376: f(x)= 77.47504174529129
# differential_evolution step 377: f(x)= 77.47504174529129
# differential_evolution step 378: f(x)= 77.47504174529129
# differential_evolution step 379: f(x)= 77.47504174529129
# differential_evolution step 380: f(x)= 77.47504174529129
# differential_evolution step 381: f(x)= 77.47504174529129
# differential_evolution step 382: f(x)= 77.47504174529129
# differential_evolution step 383: f(x)= 77.47504174529129
# differential_evolution step 384: f(x)= 77.47504174529129
# differential_evolution step 385: f(x)= 77.47504174529129
# differential_evolution step 386: f(x)= 77.47504174529129
# differential_evolution step 387: f(x)= 77.47504174529129
# differential_evolution step 388: f(x)= 77.47504174529129
# differential_evolution step 389: f(x)= 77.47504174529129
# differential_evolution step 390: f(x)= 77.47504174529129
# differential_evolution step 391: f(x)= 77.47504174529129
# differential_evolution step 392: f(x)= 77.47504174529129
# differential_evolution step 393: f(x)= 77.30982426090976
# differential_evolution step 394: f(x)= 77.30982426090976
# differential_evolution step 395: f(x)= 77.06955592414262
# differential_evolution step 396: f(x)= 77.06955592414262
# differential_evolution step 397: f(x)= 76.8722567830607
# differential_evolution step 398: f(x)= 76.8722567830607
# differential_evolution step 399: f(x)= 76.8722567830607
# differential_evolution step 400: f(x)= 76.8722567830607
# differential_evolution step 401: f(x)= 76.8722567830607
# differential_evolution step 402: f(x)= 76.8722567830607
# differential_evolution step 403: f(x)= 76.86709342370833
# differential_evolution step 404: f(x)= 76.86709342370833
# differential_evolution step 405: f(x)= 76.86709342370833
# differential_evolution step 406: f(x)= 76.86709342370833
# differential_evolution step 407: f(x)= 76.73850540218632
# differential_evolution step 408: f(x)= 76.73850540218632
# differential_evolution step 409: f(x)= 76.73850540218632
# differential_evolution step 410: f(x)= 76.7017938021772
# differential_evolution step 411: f(x)= 75.93317955753265
# differential_evolution step 412: f(x)= 75.93317955753265
# differential_evolution step 413: f(x)= 75.93317955753265
# differential_evolution step 414: f(x)= 75.93317955753265
# differential_evolution step 415: f(x)= 75.93317955753265
# differential_evolution step 416: f(x)= 75.93317955753265
# differential_evolution step 417: f(x)= 75.72914142473275
# differential_evolution step 418: f(x)= 75.72914142473275
# differential_evolution step 419: f(x)= 75.72914142473275
# differential_evolution step 420: f(x)= 75.72914142473275
# differential_evolution step 421: f(x)= 75.72914142473275
# differential_evolution step 422: f(x)= 75.72914142473275
# differential_evolution step 423: f(x)= 75.72914142473275
# differential_evolution step 424: f(x)= 75.72914142473275
# differential_evolution step 425: f(x)= 75.72914142473275
# differential_evolution step 426: f(x)= 75.72914142473275
# differential_evolution step 427: f(x)= 75.72914142473275
# differential_evolution step 428: f(x)= 75.72914142473275
# differential_evolution step 429: f(x)= 75.68952263623582
# differential_evolution step 430: f(x)= 75.68952263623582
# differential_evolution step 431: f(x)= 75.68952263623582
# differential_evolution step 432: f(x)= 75.53261131438077
# differential_evolution step 433: f(x)= 75.53261131438077
# differential_evolution step 434: f(x)= 75.53261131438077
# differential_evolution step 435: f(x)= 75.53261131438077
# differential_evolution step 436: f(x)= 75.02188407731298
# differential_evolution step 437: f(x)= 75.02188407731298
# differential_evolution step 438: f(x)= 75.02188407731298
# differential_evolution step 439: f(x)= 75.02188407731298
# differential_evolution step 440: f(x)= 75.02188407731298
# differential_evolution step 441: f(x)= 74.90376792222503
# differential_evolution step 442: f(x)= 74.90376792222503
# differential_evolution step 443: f(x)= 74.75561121028983
# differential_evolution step 444: f(x)= 74.75561121028983
# differential_evolution step 445: f(x)= 74.69760664182893
# differential_evolution step 446: f(x)= 74.69760664182893
# differential_evolution step 447: f(x)= 74.69760664182893
# differential_evolution step 448: f(x)= 74.69760664182893
# differential_evolution step 449: f(x)= 74.69760664182893
# differential_evolution step 450: f(x)= 74.498222703921
# differential_evolution step 451: f(x)= 74.09902631541306
# differential_evolution step 452: f(x)= 73.5952085051449
# differential_evolution step 453: f(x)= 73.5952085051449
# differential_evolution step 454: f(x)= 72.34707677449141
# differential_evolution step 455: f(x)= 72.34707677449141
# differential_evolution step 456: f(x)= 72.34707677449141
# differential_evolution step 457: f(x)= 72.34707677449141
# differential_evolution step 458: f(x)= 72.34707677449141
# differential_evolution step 459: f(x)= 72.34707677449141
# differential_evolution step 460: f(x)= 72.34707677449141
# differential_evolution step 461: f(x)= 71.26757499528416
# differential_evolution step 462: f(x)= 71.26757499528416
# differential_evolution step 463: f(x)= 71.26757499528416
# differential_evolution step 464: f(x)= 71.26757499528416
# differential_evolution step 465: f(x)= 71.26757499528416
# differential_evolution step 466: f(x)= 71.26757499528416
# differential_evolution step 467: f(x)= 71.26757499528416
# differential_evolution step 468: f(x)= 71.26757499528416
# differential_evolution step 469: f(x)= 71.26757499528416
# differential_evolution step 470: f(x)= 71.26757499528416
# differential_evolution step 471: f(x)= 71.26757499528416
# differential_evolution step 472: f(x)= 71.26757499528416
# differential_evolution step 473: f(x)= 71.26757499528416
# differential_evolution step 474: f(x)= 71.26757499528416
# differential_evolution step 475: f(x)= 71.26757499528416
# differential_evolution step 476: f(x)= 71.17597351053115
# differential_evolution step 477: f(x)= 71.17597351053115
# differential_evolution step 478: f(x)= 71.17597351053115
# differential_evolution step 479: f(x)= 70.90933287828138
# differential_evolution step 480: f(x)= 70.90933287828138
# differential_evolution step 481: f(x)= 70.90933287828138
# differential_evolution step 482: f(x)= 70.90933287828138
# differential_evolution step 483: f(x)= 70.90933287828138
# differential_evolution step 484: f(x)= 70.90933287828138
# differential_evolution step 485: f(x)= 70.52226564400827
# differential_evolution step 486: f(x)= 70.31961660111291
# differential_evolution step 487: f(x)= 66.879456889549
# differential_evolution step 488: f(x)= 66.879456889549
# differential_evolution step 489: f(x)= 66.879456889549
# differential_evolution step 490: f(x)= 66.879456889549
# differential_evolution step 491: f(x)= 66.81509943307869
# differential_evolution step 492: f(x)= 66.81509943307869
# differential_evolution step 493: f(x)= 66.81509943307869
# differential_evolution step 494: f(x)= 66.81509943307869
# differential_evolution step 495: f(x)= 66.60105613418098
# differential_evolution step 496: f(x)= 66.60105613418098
# differential_evolution step 497: f(x)= 66.60105613418098
# differential_evolution step 498: f(x)= 65.70390660325143
# differential_evolution step 499: f(x)= 64.01100731741623
# differential_evolution step 500: f(x)= 64.01100731741623
# differential_evolution step 501: f(x)= 64.01100731741623
# differential_evolution step 502: f(x)= 64.01100731741623
# differential_evolution step 503: f(x)= 64.01100731741623
# differential_evolution step 504: f(x)= 64.01100731741623
# differential_evolution step 505: f(x)= 64.01100731741623
# differential_evolution step 506: f(x)= 64.01100731741623
# differential_evolution step 507: f(x)= 64.01100731741623
# differential_evolution step 508: f(x)= 63.85422677511706
# differential_evolution step 509: f(x)= 63.85422677511706
# differential_evolution step 510: f(x)= 63.85422677511706
# differential_evolution step 511: f(x)= 63.85422677511706
# differential_evolution step 512: f(x)= 63.85422677511706
# differential_evolution step 513: f(x)= 63.85422677511706
# differential_evolution step 514: f(x)= 63.470755396447956
# differential_evolution step 515: f(x)= 63.470755396447956
# differential_evolution step 516: f(x)= 63.470755396447956
# differential_evolution step 517: f(x)= 63.470755396447956
# differential_evolution step 518: f(x)= 61.82294090628991
# differential_evolution step 519: f(x)= 61.82294090628991
# differential_evolution step 520: f(x)= 59.36407407050636
# differential_evolution step 521: f(x)= 59.36407407050636
# differential_evolution step 522: f(x)= 59.36407407050636
# differential_evolution step 523: f(x)= 59.36407407050636
# differential_evolution step 524: f(x)= 59.36407407050636
# differential_evolution step 525: f(x)= 59.36407407050636
# differential_evolution step 526: f(x)= 59.36407407050636
# differential_evolution step 527: f(x)= 58.67756581559698
# differential_evolution step 528: f(x)= 58.06702906451429
# differential_evolution step 529: f(x)= 58.06702906451429
# differential_evolution step 530: f(x)= 58.06702906451429
# differential_evolution step 531: f(x)= 58.06702906451429
# differential_evolution step 532: f(x)= 58.06702906451429
# differential_evolution step 533: f(x)= 58.06702906451429
# differential_evolution step 534: f(x)= 58.06702906451429
# differential_evolution step 535: f(x)= 58.06702906451429
# differential_evolution step 536: f(x)= 56.441361649979335
# differential_evolution step 537: f(x)= 56.441361649979335
# differential_evolution step 538: f(x)= 55.86949072131991
# differential_evolution step 539: f(x)= 55.86949072131991
# differential_evolution step 540: f(x)= 55.86949072131991
# differential_evolution step 541: f(x)= 55.86949072131991
# differential_evolution step 542: f(x)= 55.86949072131991
# differential_evolution step 543: f(x)= 55.86949072131991
# differential_evolution step 544: f(x)= 55.86949072131991
# differential_evolution step 545: f(x)= 55.86949072131991
# differential_evolution step 546: f(x)= 55.86949072131991
# differential_evolution step 547: f(x)= 55.86949072131991
# differential_evolution step 548: f(x)= 55.387170907444364
# differential_evolution step 549: f(x)= 55.387170907444364
# differential_evolution step 550: f(x)= 55.387170907444364
# differential_evolution step 551: f(x)= 55.387170907444364
# differential_evolution step 552: f(x)= 55.19715793228989
# differential_evolution step 553: f(x)= 55.19715793228989
# differential_evolution step 554: f(x)= 55.19715793228989
# differential_evolution step 555: f(x)= 55.19715793228989
# differential_evolution step 556: f(x)= 54.294571559269116
# differential_evolution step 557: f(x)= 54.294571559269116
# differential_evolution step 558: f(x)= 54.294571559269116
# differential_evolution step 559: f(x)= 54.294571559269116
# differential_evolution step 560: f(x)= 54.0151982189567
# differential_evolution step 561: f(x)= 54.0151982189567
# differential_evolution step 562: f(x)= 54.0151982189567
# differential_evolution step 563: f(x)= 54.0151982189567
# differential_evolution step 564: f(x)= 54.0151982189567
# differential_evolution step 565: f(x)= 54.0151982189567
# differential_evolution step 566: f(x)= 54.0151982189567
# differential_evolution step 567: f(x)= 54.0151982189567
# differential_evolution step 568: f(x)= 54.0151982189567
# differential_evolution step 569: f(x)= 54.0151982189567
# differential_evolution step 570: f(x)= 54.0151982189567
# differential_evolution step 571: f(x)= 54.0151982189567
# differential_evolution step 572: f(x)= 54.0151982189567
# differential_evolution step 573: f(x)= 54.0151982189567
# differential_evolution step 574: f(x)= 54.0151982189567
# differential_evolution step 575: f(x)= 54.0151982189567
# differential_evolution step 576: f(x)= 54.0151982189567
# differential_evolution step 577: f(x)= 54.0151982189567
# differential_evolution step 578: f(x)= 53.38593177409371
# differential_evolution step 579: f(x)= 53.38593177409371
# differential_evolution step 580: f(x)= 53.38593177409371
# differential_evolution step 581: f(x)= 53.38593177409371
# differential_evolution step 582: f(x)= 53.38593177409371
# differential_evolution step 583: f(x)= 53.38593177409371
# differential_evolution step 584: f(x)= 53.38593177409371
# differential_evolution step 585: f(x)= 53.38593177409371
# differential_evolution step 586: f(x)= 53.38593177409371
# differential_evolution step 587: f(x)= 53.38593177409371
# differential_evolution step 588: f(x)= 52.832469899671985
# differential_evolution step 589: f(x)= 52.832469899671985
# differential_evolution step 590: f(x)= 52.832469899671985
# differential_evolution step 591: f(x)= 52.832469899671985
# differential_evolution step 592: f(x)= 52.54689912145727
# differential_evolution step 593: f(x)= 52.54689912145727
# differential_evolution step 594: f(x)= 52.54689912145727
# differential_evolution step 595: f(x)= 52.54689912145727
# differential_evolution step 596: f(x)= 52.54689912145727
# differential_evolution step 597: f(x)= 52.54689912145727
# differential_evolution step 598: f(x)= 52.54689912145727
# differential_evolution step 599: f(x)= 52.36800604077569
# differential_evolution step 600: f(x)= 52.36800604077569
# differential_evolution step 601: f(x)= 52.36800604077569
# differential_evolution step 602: f(x)= 52.36800604077569
# differential_evolution step 603: f(x)= 52.36800604077569
# differential_evolution step 604: f(x)= 52.36800604077569
# differential_evolution step 605: f(x)= 52.36800604077569
# differential_evolution step 606: f(x)= 52.36800604077569
# differential_evolution step 607: f(x)= 52.30521162987918
# differential_evolution step 608: f(x)= 52.30521162987918
# differential_evolution step 609: f(x)= 52.30521162987918
# differential_evolution step 610: f(x)= 52.30037247586941
# differential_evolution step 611: f(x)= 52.30037247586941
# differential_evolution step 612: f(x)= 52.30037247586941
# differential_evolution step 613: f(x)= 52.30037247586941
# differential_evolution step 614: f(x)= 52.30037247586941
# differential_evolution step 615: f(x)= 52.30037247586941
# differential_evolution step 616: f(x)= 52.30037247586941
# differential_evolution step 617: f(x)= 52.30037247586941
# differential_evolution step 618: f(x)= 52.30037247586941
# differential_evolution step 619: f(x)= 52.30037247586941
# differential_evolution step 620: f(x)= 52.30037247586941
# differential_evolution step 621: f(x)= 52.30037247586941
# differential_evolution step 622: f(x)= 52.30037247586941
# differential_evolution step 623: f(x)= 52.30037247586941
# differential_evolution step 624: f(x)= 52.30037247586941
# differential_evolution step 625: f(x)= 52.30037247586941
# differential_evolution step 626: f(x)= 52.134112052414984
# differential_evolution step 627: f(x)= 52.134112052414984
# differential_evolution step 628: f(x)= 52.134112052414984
# differential_evolution step 629: f(x)= 52.134112052414984
# differential_evolution step 630: f(x)= 52.134112052414984
# differential_evolution step 631: f(x)= 52.134112052414984
# differential_evolution step 632: f(x)= 52.134112052414984
# differential_evolution step 633: f(x)= 52.11982223385085
# differential_evolution step 634: f(x)= 52.10419416905769
# differential_evolution step 635: f(x)= 52.10419416905769
# differential_evolution step 636: f(x)= 52.10419416905769
# differential_evolution step 637: f(x)= 52.10419416905769
# differential_evolution step 638: f(x)= 52.10419416905769
# differential_evolution step 639: f(x)= 52.09263059267157
# differential_evolution step 640: f(x)= 52.08779179070147
# differential_evolution step 641: f(x)= 52.08779179070147
# differential_evolution step 642: f(x)= 52.08779179070147
# differential_evolution step 643: f(x)= 52.08779179070147
# differential_evolution step 644: f(x)= 52.08779179070147
# differential_evolution step 645: f(x)= 52.08779179070147
# differential_evolution step 646: f(x)= 52.08779179070147
# differential_evolution step 647: f(x)= 51.97607727181711
# differential_evolution step 648: f(x)= 51.97607727181711
# differential_evolution step 649: f(x)= 51.97607727181711
# differential_evolution step 650: f(x)= 51.97607727181711
# differential_evolution step 651: f(x)= 51.97607727181711
# differential_evolution step 652: f(x)= 51.957452585477085
# differential_evolution step 653: f(x)= 51.957452585477085
# differential_evolution step 654: f(x)= 51.957452585477085
# differential_evolution step 655: f(x)= 51.957452585477085
# differential_evolution step 656: f(x)= 51.957452585477085
# differential_evolution step 657: f(x)= 51.957452585477085
# differential_evolution step 658: f(x)= 51.94663623882999
# differential_evolution step 659: f(x)= 51.94663623882999
# differential_evolution step 660: f(x)= 51.94663623882999
# differential_evolution step 661: f(x)= 51.94663623882999
# differential_evolution step 662: f(x)= 51.94663623882999
# differential_evolution step 663: f(x)= 51.94663623882999
# differential_evolution step 664: f(x)= 51.94663623882999
# differential_evolution step 665: f(x)= 51.94663623882999
# differential_evolution step 666: f(x)= 51.84486112890279
# differential_evolution step 667: f(x)= 51.84486112890279
# differential_evolution step 668: f(x)= 51.84486112890279
# differential_evolution step 669: f(x)= 51.84486112890279
# differential_evolution step 670: f(x)= 51.82980253750973
# differential_evolution step 671: f(x)= 51.82980253750973
# differential_evolution step 672: f(x)= 51.82980253750973
# differential_evolution step 673: f(x)= 51.82980253750973
# differential_evolution step 674: f(x)= 51.82980253750973
# differential_evolution step 675: f(x)= 51.82980253750973
# differential_evolution step 676: f(x)= 51.82980253750973
# differential_evolution step 677: f(x)= 51.82980253750973
# differential_evolution step 678: f(x)= 51.82980253750973
# differential_evolution step 679: f(x)= 51.82980253750973
# differential_evolution step 680: f(x)= 51.82980253750973
# differential_evolution step 681: f(x)= 51.82980253750973
# differential_evolution step 682: f(x)= 51.82980253750973
# differential_evolution step 683: f(x)= 51.82980253750973
# differential_evolution step 684: f(x)= 51.801158601039866
# differential_evolution step 685: f(x)= 51.801158601039866
# differential_evolution step 686: f(x)= 51.801158601039866
# differential_evolution step 687: f(x)= 51.801158601039866
# differential_evolution step 688: f(x)= 51.801158601039866
# differential_evolution step 689: f(x)= 51.801158601039866
# differential_evolution step 690: f(x)= 51.801158601039866
# differential_evolution step 691: f(x)= 51.801158601039866
# differential_evolution step 692: f(x)= 51.801158601039866
# differential_evolution step 693: f(x)= 51.801158601039866
# differential_evolution step 694: f(x)= 51.790853176251034
# differential_evolution step 695: f(x)= 51.790853176251034
# differential_evolution step 696: f(x)= 51.790853176251034
# differential_evolution step 697: f(x)= 51.790853176251034
# differential_evolution step 698: f(x)= 51.790853176251034
# differential_evolution step 699: f(x)= 51.790853176251034
# differential_evolution step 700: f(x)= 51.7907770057127
# differential_evolution step 701: f(x)= 51.7907770057127
# differential_evolution step 702: f(x)= 51.7907770057127
# differential_evolution step 703: f(x)= 51.7907770057127
# differential_evolution step 704: f(x)= 51.7907770057127
# differential_evolution step 705: f(x)= 51.7907770057127
# differential_evolution step 706: f(x)= 51.7907770057127
# differential_evolution step 707: f(x)= 51.78318553389568
# differential_evolution step 708: f(x)= 51.78318553389568
# differential_evolution step 709: f(x)= 51.78318553389568
# differential_evolution step 710: f(x)= 51.78318553389568
# differential_evolution step 711: f(x)= 51.78318553389568
# differential_evolution step 712: f(x)= 51.74291346239769
# differential_evolution step 713: f(x)= 51.74291346239769
# differential_evolution step 714: f(x)= 51.74291346239769
# differential_evolution step 715: f(x)= 51.74291346239769
# differential_evolution step 716: f(x)= 51.74291346239769
# differential_evolution step 717: f(x)= 51.74268481283224
# differential_evolution step 718: f(x)= 51.74268481283224
# differential_evolution step 719: f(x)= 51.74268481283224
# differential_evolution step 720: f(x)= 51.74268481283224
# differential_evolution step 721: f(x)= 51.74268481283224
# differential_evolution step 722: f(x)= 51.72540132624928
# differential_evolution step 723: f(x)= 51.72540132624928
# differential_evolution step 724: f(x)= 51.72540132624928
# differential_evolution step 725: f(x)= 51.72540132624928
# differential_evolution step 726: f(x)= 51.72540132624928
# differential_evolution step 727: f(x)= 51.72540132624928
# differential_evolution step 728: f(x)= 51.72540132624928
# differential_evolution step 729: f(x)= 51.72540132624928
# differential_evolution step 730: f(x)= 51.72540132624928
# differential_evolution step 731: f(x)= 51.71748453134
# differential_evolution step 732: f(x)= 51.71748453134
# differential_evolution step 733: f(x)= 51.71748453134
# differential_evolution step 734: f(x)= 51.71748453134
# differential_evolution step 735: f(x)= 51.71748453134
# differential_evolution step 736: f(x)= 51.71748453134
# differential_evolution step 737: f(x)= 51.712741751338456
# differential_evolution step 738: f(x)= 51.712741751338456
# differential_evolution step 739: f(x)= 51.712741751338456
# differential_evolution step 740: f(x)= 51.712741751338456
# differential_evolution step 741: f(x)= 51.712741751338456
# differential_evolution step 742: f(x)= 51.712741751338456
# differential_evolution step 743: f(x)= 51.712741751338456
# differential_evolution step 744: f(x)= 51.712741751338456
# differential_evolution step 745: f(x)= 51.71053203437917
# differential_evolution step 746: f(x)= 51.71053203437917
# differential_evolution step 747: f(x)= 51.71053203437917
# differential_evolution step 748: f(x)= 51.71053203437917
# differential_evolution step 749: f(x)= 51.71053203437917
# differential_evolution step 750: f(x)= 51.71053203437917
# differential_evolution step 751: f(x)= 51.71053203437917
# differential_evolution step 752: f(x)= 51.71053203437917
# differential_evolution step 753: f(x)= 51.71053203437917
# differential_evolution step 754: f(x)= 51.70857424243013
# differential_evolution step 755: f(x)= 51.70857424243013
# differential_evolution step 756: f(x)= 51.70857424243013
# differential_evolution step 757: f(x)= 51.70857424243013
# differential_evolution step 758: f(x)= 51.70857424243013
# differential_evolution step 759: f(x)= 51.70857424243013
# differential_evolution step 760: f(x)= 51.70857424243013
# differential_evolution step 761: f(x)= 51.70857424243013
# differential_evolution step 762: f(x)= 51.70857424243013
# differential_evolution step 763: f(x)= 51.70857424243013
# differential_evolution step 764: f(x)= 51.70857424243013
# differential_evolution step 765: f(x)= 51.70857424243013
# differential_evolution step 766: f(x)= 51.70658439733982
# differential_evolution step 767: f(x)= 51.70658439733982
# differential_evolution step 768: f(x)= 51.70658439733982
# differential_evolution step 769: f(x)= 51.70658439733982
# differential_evolution step 770: f(x)= 51.70658439733982
# differential_evolution step 771: f(x)= 51.70658439733982
# differential_evolution step 772: f(x)= 51.705358357814205
# differential_evolution step 773: f(x)= 51.705358357814205
# differential_evolution step 774: f(x)= 51.705358357814205
# differential_evolution step 775: f(x)= 51.705358357814205
# differential_evolution step 776: f(x)= 51.705358357814205
# differential_evolution step 777: f(x)= 51.705358357814205
# differential_evolution step 778: f(x)= 51.705358357814205
# differential_evolution step 779: f(x)= 51.705358357814205
# differential_evolution step 780: f(x)= 51.705358357814205
# differential_evolution step 781: f(x)= 51.705358357814205
# differential_evolution step 782: f(x)= 51.705358357814205
# differential_evolution step 783: f(x)= 51.705358357814205
# differential_evolution step 784: f(x)= 51.705358357814205
# differential_evolution step 785: f(x)= 51.705358357814205
# differential_evolution step 786: f(x)= 51.705358357814205
# differential_evolution step 787: f(x)= 51.705358357814205
# differential_evolution step 788: f(x)= 51.705358357814205
# differential_evolution step 789: f(x)= 51.70492690965578
# differential_evolution step 790: f(x)= 51.70492690965578
# differential_evolution step 791: f(x)= 51.70492690965578
# differential_evolution step 792: f(x)= 51.704345747768436
# differential_evolution step 793: f(x)= 51.70410167405415
# differential_evolution step 794: f(x)= 51.70410167405415
# differential_evolution step 795: f(x)= 51.70410167405415
# differential_evolution step 796: f(x)= 51.70410167405415
# differential_evolution step 797: f(x)= 51.70410167405415
# differential_evolution step 798: f(x)= 51.70410167405415
# differential_evolution step 799: f(x)= 51.70410167405415
# differential_evolution step 800: f(x)= 51.70410167405415
# differential_evolution step 801: f(x)= 51.70410167405415
# differential_evolution step 802: f(x)= 51.703706558552504
# differential_evolution step 803: f(x)= 51.703706558552504
# differential_evolution step 804: f(x)= 51.703706558552504
# differential_evolution step 805: f(x)= 51.703706558552504
# differential_evolution step 806: f(x)= 51.70331587450688
# differential_evolution step 807: f(x)= 51.70331587450688
# differential_evolution step 808: f(x)= 51.70331587450688
# differential_evolution step 809: f(x)= 51.70331587450688
# differential_evolution step 810: f(x)= 51.70331587450688
# differential_evolution step 811: f(x)= 51.70321707402652
# differential_evolution step 812: f(x)= 51.70321707402652
# differential_evolution step 813: f(x)= 51.70321707402652
# differential_evolution step 814: f(x)= 51.70321707402652
# differential_evolution step 815: f(x)= 51.70321707402652
# differential_evolution step 816: f(x)= 51.70321707402652
# differential_evolution step 817: f(x)= 51.70321707402652
# differential_evolution step 818: f(x)= 51.70321707402652
# differential_evolution step 819: f(x)= 51.70321707402652
# differential_evolution step 820: f(x)= 51.70321707402652
# differential_evolution step 821: f(x)= 51.70321707402652
# differential_evolution step 822: f(x)= 51.70321707402652
# differential_evolution step 823: f(x)= 51.70321707402652
# differential_evolution step 824: f(x)= 51.70321707402652
# differential_evolution step 825: f(x)= 51.70321707402652
# differential_evolution step 826: f(x)= 51.70321707402652
# differential_evolution step 827: f(x)= 51.70321707402652
# differential_evolution step 828: f(x)= 51.70321707402652
# differential_evolution step 829: f(x)= 51.70321707402652
# differential_evolution step 830: f(x)= 51.70321707402652
# differential_evolution step 831: f(x)= 51.702649773460834
# differential_evolution step 832: f(x)= 51.702649773460834
# differential_evolution step 833: f(x)= 51.702649773460834
# differential_evolution step 834: f(x)= 51.702649773460834
# differential_evolution step 835: f(x)= 51.702649773460834
# differential_evolution step 836: f(x)= 51.702649773460834
# differential_evolution step 837: f(x)= 51.702649773460834
# differential_evolution step 838: f(x)= 51.702649773460834
# differential_evolution step 839: f(x)= 51.702649773460834
# differential_evolution step 840: f(x)= 51.702649773460834
# differential_evolution step 841: f(x)= 51.702649773460834
# differential_evolution step 842: f(x)= 51.702649773460834
# differential_evolution step 843: f(x)= 51.702649773460834
# differential_evolution step 844: f(x)= 51.702649773460834
# differential_evolution step 845: f(x)= 51.702649773460834
# differential_evolution step 846: f(x)= 51.702649773460834
# differential_evolution step 847: f(x)= 51.702649773460834
# differential_evolution step 848: f(x)= 51.702649773460834
# differential_evolution step 849: f(x)= 51.702649773460834
# differential_evolution step 850: f(x)= 51.70248247577439
# differential_evolution step 851: f(x)= 51.70248247577439
# differential_evolution step 852: f(x)= 51.70248247577439
# differential_evolution step 853: f(x)= 51.70248247577439
# differential_evolution step 854: f(x)= 51.70248247577439
# differential_evolution step 855: f(x)= 51.70248247577439
# differential_evolution step 856: f(x)= 51.70248247577439
# differential_evolution step 857: f(x)= 51.70248247577439
# differential_evolution step 858: f(x)= 51.70248247577439
# differential_evolution step 859: f(x)= 51.70227420958018
# differential_evolution step 860: f(x)= 51.70227420958018
# differential_evolution step 861: f(x)= 51.70227420958018
# differential_evolution step 862: f(x)= 51.70227420958018
# differential_evolution step 863: f(x)= 51.70227420958018
# differential_evolution step 864: f(x)= 51.70227420958018
# differential_evolution step 865: f(x)= 51.70227420958018
# differential_evolution step 866: f(x)= 51.70227420958018
# differential_evolution step 867: f(x)= 51.70227420958018
# differential_evolution step 868: f(x)= 51.70227420958018
# differential_evolution step 869: f(x)= 51.70204486222577
# differential_evolution step 870: f(x)= 51.70204486222577
# differential_evolution step 871: f(x)= 51.70180112959802
# differential_evolution step 872: f(x)= 51.70180112959802
# differential_evolution step 873: f(x)= 51.70180112959802
# differential_evolution step 874: f(x)= 51.70180112959802
# differential_evolution step 875: f(x)= 51.70180112959802
# differential_evolution step 876: f(x)= 51.701752837781285
# differential_evolution step 877: f(x)= 51.701752837781285
# differential_evolution step 878: f(x)= 51.70169595362208
# differential_evolution step 879: f(x)= 51.701590317297445
# differential_evolution step 880: f(x)= 51.701590317297445
# differential_evolution step 881: f(x)= 51.701590317297445
# differential_evolution step 882: f(x)= 51.701590317297445
# differential_evolution step 883: f(x)= 51.701590317297445
# differential_evolution step 884: f(x)= 51.701590317297445
# differential_evolution step 885: f(x)= 51.701590317297445
# differential_evolution step 886: f(x)= 51.701590317297445
# differential_evolution step 887: f(x)= 51.701590317297445
# differential_evolution step 888: f(x)= 51.701590317297445
# differential_evolution step 889: f(x)= 51.701590317297445
# differential_evolution step 890: f(x)= 51.701590317297445
# differential_evolution step 891: f(x)= 51.70156259373449
# differential_evolution step 892: f(x)= 51.70156259373449
# differential_evolution step 893: f(x)= 51.70156259373449
# differential_evolution step 894: f(x)= 51.70156259373449
# differential_evolution step 895: f(x)= 51.70156259373449
# differential_evolution step 896: f(x)= 51.70156259373449
# differential_evolution step 897: f(x)= 51.70156259373449
# differential_evolution step 898: f(x)= 51.70156259373449
# differential_evolution step 899: f(x)= 51.70156259373449
# differential_evolution step 900: f(x)= 51.70156259373449
# differential_evolution step 901: f(x)= 51.7015146629563
# differential_evolution step 902: f(x)= 51.7015146629563
# differential_evolution step 903: f(x)= 51.7015146629563
# differential_evolution step 904: f(x)= 51.7015146629563
# differential_evolution step 905: f(x)= 51.7015146629563
# differential_evolution step 906: f(x)= 51.7015146629563
# differential_evolution step 907: f(x)= 51.7015146629563
# differential_evolution step 908: f(x)= 51.7015146629563
# differential_evolution step 909: f(x)= 51.7015146629563
# differential_evolution step 910: f(x)= 51.7015146629563
# differential_evolution step 911: f(x)= 51.7015146629563
# differential_evolution step 912: f(x)= 51.7015146629563
# differential_evolution step 913: f(x)= 51.7015146629563
# differential_evolution step 914: f(x)= 51.7015146629563
# differential_evolution step 915: f(x)= 51.701401432665314
# differential_evolution step 916: f(x)= 51.701401432665314
# differential_evolution step 917: f(x)= 51.701401432665314
# differential_evolution step 918: f(x)= 51.701401432665314
# differential_evolution step 919: f(x)= 51.701401432665314
# differential_evolution step 920: f(x)= 51.701401432665314
# differential_evolution step 921: f(x)= 51.701401432665314
# differential_evolution step 922: f(x)= 51.701401432665314
# differential_evolution step 923: f(x)= 51.701401432665314
# differential_evolution step 924: f(x)= 51.701401432665314
# differential_evolution step 925: f(x)= 51.7013573312036
# differential_evolution step 926: f(x)= 51.7013573312036
# differential_evolution step 927: f(x)= 51.7013573312036
# differential_evolution step 928: f(x)= 51.7013573312036
# differential_evolution step 929: f(x)= 51.7013573312036
# differential_evolution step 930: f(x)= 51.701336172018515
# differential_evolution step 931: f(x)= 51.701336172018515
# differential_evolution step 932: f(x)= 51.701336172018515
# differential_evolution step 933: f(x)= 51.70132202946355
# differential_evolution step 934: f(x)= 51.70131529634137
# differential_evolution step 935: f(x)= 51.70130150015819
# differential_evolution step 936: f(x)= 51.70130150015819
# differential_evolution step 937: f(x)= 51.7012835209901
# differential_evolution step 938: f(x)= 51.7012835209901
# differential_evolution step 939: f(x)= 51.70126640066214
# differential_evolution step 940: f(x)= 51.70126640066214
# differential_evolution step 941: f(x)= 51.70126640066214
# differential_evolution step 942: f(x)= 51.70126640066214
# differential_evolution step 943: f(x)= 51.70126640066214
# differential_evolution step 944: f(x)= 51.701217865695725
# differential_evolution step 945: f(x)= 51.701217865695725
# differential_evolution step 946: f(x)= 51.701217865695725
# differential_evolution step 947: f(x)= 51.701217865695725
# differential_evolution step 948: f(x)= 51.701217865695725
# differential_evolution step 949: f(x)= 51.701217865695725
# differential_evolution step 950: f(x)= 51.701217865695725
# differential_evolution step 951: f(x)= 51.701217865695725
# differential_evolution step 952: f(x)= 51.701217865695725
# differential_evolution step 953: f(x)= 51.701217865695725
# differential_evolution step 954: f(x)= 51.701217865695725
# differential_evolution step 955: f(x)= 51.701217865695725
# differential_evolution step 956: f(x)= 51.701217865695725
# differential_evolution step 957: f(x)= 51.701217865695725
# differential_evolution step 958: f(x)= 51.701217865695725
# differential_evolution step 959: f(x)= 51.701217865695725
# differential_evolution step 960: f(x)= 51.701217865695725
# differential_evolution step 961: f(x)= 51.701217865695725
# differential_evolution step 962: f(x)= 51.701217865695725
# differential_evolution step 963: f(x)= 51.701217865695725
# differential_evolution step 964: f(x)= 51.701217865695725
# differential_evolution step 965: f(x)= 51.701217865695725
# differential_evolution step 966: f(x)= 51.70121648551837
# differential_evolution step 967: f(x)= 51.70121648551837
# differential_evolution step 968: f(x)= 51.70121648551837
# differential_evolution step 969: f(x)= 51.70121648551837
# differential_evolution step 970: f(x)= 51.70121648551837
# differential_evolution step 971: f(x)= 51.70121648551837
# differential_evolution step 972: f(x)= 51.70121648551837
# differential_evolution step 973: f(x)= 51.7012152431536
# differential_evolution step 974: f(x)= 51.7012152431536
# differential_evolution step 975: f(x)= 51.7012152431536
# differential_evolution step 976: f(x)= 51.7012152431536
# differential_evolution step 977: f(x)= 51.701199083581386
# differential_evolution step 978: f(x)= 51.701199083581386
# differential_evolution step 979: f(x)= 51.701177322733045
# differential_evolution step 980: f(x)= 51.701177322733045
# differential_evolution step 981: f(x)= 51.701177322733045
# differential_evolution step 982: f(x)= 51.701177322733045
# differential_evolution step 983: f(x)= 51.701177322733045
# differential_evolution step 984: f(x)= 51.701177322733045
# differential_evolution step 985: f(x)= 51.701177322733045
# differential_evolution step 986: f(x)= 51.701177322733045
# differential_evolution step 987: f(x)= 51.701177322733045
# differential_evolution step 988: f(x)= 51.701177322733045
# differential_evolution step 989: f(x)= 51.701177322733045
# differential_evolution step 990: f(x)= 51.701177322733045
# differential_evolution step 991: f(x)= 51.701177322733045
# differential_evolution step 992: f(x)= 51.701177322733045
# differential_evolution step 993: f(x)= 51.701177322733045
# differential_evolution step 994: f(x)= 51.701177322733045
# differential_evolution step 995: f(x)= 51.701177322733045
# differential_evolution step 996: f(x)= 51.701177322733045
# differential_evolution step 997: f(x)= 51.701177322733045
# differential_evolution step 998: f(x)= 51.701177322733045
# differential_evolution step 999: f(x)= 51.70117549274643
# differential_evolution step 1000: f(x)= 51.701172050599304
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [20.          1.36528589  0.46347788 51.71544111 17.97834139  4.80456599
#   0.76618756 60.76035292  2.37303243 17.38366664  1.24111681 47.5005797 ]
# Chi quadro minimo: 51.70114734229554

# %%
# Plots:
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, 
                                         sigma = radial_profile_error_HA, maxfev = 10000, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=20.0000, r_e=1.3025, n=0.4577, x_0=51.7130
# Sérsic 2: I_e=15.4965, r_e=5.3000, n=0.8594, x_0=60.7796
# Sérsic 3: I_e=2.5057, r_e=16.1666, n=1.2126, x_0=47.5873
# [9.13613521 0.25405746 0.37227023 0.07847335 0.60865721 0.13575379
#  0.02957316 0.05149558 0.28509742 0.61516255 0.05465299 0.49270467]
# 93.47942602953528
# 121.065632926087 93.47942602953528 148.74146826139238 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
      (0, 20),
    (0, 50),
    (0.1, 10),
    (0, 100),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62), 

    (0, 20),
    (0, 50),
    (0.1, 10),
    (0, 100)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 38438.2461871875
# differential_evolution step 2: f(x)= 21833.505234341013
# differential_evolution step 3: f(x)= 13979.919940521995
# differential_evolution step 4: f(x)= 10639.763938505614
# differential_evolution step 5: f(x)= 4132.480668553372
# differential_evolution step 6: f(x)= 4132.480668553372
# differential_evolution step 7: f(x)= 3597.7348128258363
# differential_evolution step 8: f(x)= 3597.7348128258363
# differential_evolution step 9: f(x)= 3597.7348128258363
# differential_evolution step 10: f(x)= 3597.7348128258363
# differential_evolution step 11: f(x)= 3597.7348128258363
# differential_evolution step 12: f(x)= 3597.7348128258363
# differential_evolution step 13: f(x)= 3597.7348128258363
# differential_evolution step 14: f(x)= 3597.7348128258363
# differential_evolution step 15: f(x)= 3597.7348128258363
# differential_evolution step 16: f(x)= 3213.032175635956
# differential_evolution step 17: f(x)= 1958.8149297132256
# differential_evolution step 18: f(x)= 1915.6807605286658
# differential_evolution step 19: f(x)= 1915.6807605286658
# differential_evolution step 20: f(x)= 1089.294824926044
# differential_evolution step 21: f(x)= 1089.294824926044
# differential_evolution step 22: f(x)= 1089.294824926044
# differential_evolution step 23: f(x)= 1089.294824926044
# differential_evolution step 24: f(x)= 1089.294824926044
# differential_evolution step 25: f(x)= 1089.294824926044
# differential_evolution step 26: f(x)= 1089.294824926044
# differential_evolution step 27: f(x)= 1089.294824926044
# differential_evolution step 28: f(x)= 1089.294824926044
# differential_evolution step 29: f(x)= 1089.294824926044
# differential_evolution step 30: f(x)= 1089.294824926044
# differential_evolution step 31: f(x)= 921.3846921657691
# differential_evolution step 32: f(x)= 773.7722774520968
# differential_evolution step 33: f(x)= 773.7722774520968
# differential_evolution step 34: f(x)= 773.7722774520968
# differential_evolution step 35: f(x)= 773.7722774520968
# differential_evolution step 36: f(x)= 773.7722774520968
# differential_evolution step 37: f(x)= 716.2094444260837
# differential_evolution step 38: f(x)= 716.2094444260837
# differential_evolution step 39: f(x)= 716.2094444260837
# differential_evolution step 40: f(x)= 716.2094444260837
# differential_evolution step 41: f(x)= 624.2419255961184
# differential_evolution step 42: f(x)= 624.2419255961184
# differential_evolution step 43: f(x)= 624.2419255961184
# differential_evolution step 44: f(x)= 624.2419255961184
# differential_evolution step 45: f(x)= 624.2419255961184
# differential_evolution step 46: f(x)= 624.2419255961184
# differential_evolution step 47: f(x)= 624.2419255961184
# differential_evolution step 48: f(x)= 624.2419255961184
# differential_evolution step 49: f(x)= 569.0077421172678
# differential_evolution step 50: f(x)= 553.8315688835236
# differential_evolution step 51: f(x)= 553.8315688835236
# differential_evolution step 52: f(x)= 553.8315688835236
# differential_evolution step 53: f(x)= 553.8315688835236
# differential_evolution step 54: f(x)= 553.8315688835236
# differential_evolution step 55: f(x)= 553.8315688835236
# differential_evolution step 56: f(x)= 553.8315688835236
# differential_evolution step 57: f(x)= 519.8555741703274
# differential_evolution step 58: f(x)= 519.8555741703274
# differential_evolution step 59: f(x)= 517.1813043929257
# differential_evolution step 60: f(x)= 517.1813043929257
# differential_evolution step 61: f(x)= 517.1813043929257
# differential_evolution step 62: f(x)= 517.1813043929257
# differential_evolution step 63: f(x)= 517.1813043929257
# differential_evolution step 64: f(x)= 517.1813043929257
# differential_evolution step 65: f(x)= 517.1813043929257
# differential_evolution step 66: f(x)= 517.1813043929257
# differential_evolution step 67: f(x)= 517.1813043929257
# differential_evolution step 68: f(x)= 517.1813043929257
# differential_evolution step 69: f(x)= 517.1813043929257
# differential_evolution step 70: f(x)= 517.1813043929257
# differential_evolution step 71: f(x)= 517.1813043929257
# differential_evolution step 72: f(x)= 495.7989855426299
# differential_evolution step 73: f(x)= 495.7989855426299
# differential_evolution step 74: f(x)= 495.7989855426299
# differential_evolution step 75: f(x)= 495.7989855426299
# differential_evolution step 76: f(x)= 495.7989855426299
# differential_evolution step 77: f(x)= 495.7989855426299
# differential_evolution step 78: f(x)= 495.7989855426299
# differential_evolution step 79: f(x)= 495.7989855426299
# differential_evolution step 80: f(x)= 495.7989855426299
# differential_evolution step 81: f(x)= 495.7989855426299
# differential_evolution step 82: f(x)= 495.7989855426299
# differential_evolution step 83: f(x)= 460.21848267794616
# differential_evolution step 84: f(x)= 460.21848267794616
# differential_evolution step 85: f(x)= 460.21848267794616
# differential_evolution step 86: f(x)= 460.21848267794616
# differential_evolution step 87: f(x)= 460.21848267794616
# differential_evolution step 88: f(x)= 460.21848267794616
# differential_evolution step 89: f(x)= 460.21848267794616
# differential_evolution step 90: f(x)= 460.21848267794616
# differential_evolution step 91: f(x)= 460.21848267794616
# differential_evolution step 92: f(x)= 408.89852209893075
# differential_evolution step 93: f(x)= 408.89852209893075
# differential_evolution step 94: f(x)= 408.89852209893075
# differential_evolution step 95: f(x)= 408.89852209893075
# differential_evolution step 96: f(x)= 408.89852209893075
# differential_evolution step 97: f(x)= 408.89852209893075
# differential_evolution step 98: f(x)= 408.89852209893075
# differential_evolution step 99: f(x)= 408.89852209893075
# differential_evolution step 100: f(x)= 408.89852209893075
# differential_evolution step 101: f(x)= 408.89852209893075
# differential_evolution step 102: f(x)= 408.89852209893075
# differential_evolution step 103: f(x)= 408.89852209893075
# differential_evolution step 104: f(x)= 408.89852209893075
# differential_evolution step 105: f(x)= 408.89852209893075
# differential_evolution step 106: f(x)= 408.89852209893075
# differential_evolution step 107: f(x)= 408.89852209893075
# differential_evolution step 108: f(x)= 408.89852209893075
# differential_evolution step 109: f(x)= 408.89852209893075
# differential_evolution step 110: f(x)= 341.24817218797057
# differential_evolution step 111: f(x)= 341.24817218797057
# differential_evolution step 112: f(x)= 341.24817218797057
# differential_evolution step 113: f(x)= 341.24817218797057
# differential_evolution step 114: f(x)= 341.24817218797057
# differential_evolution step 115: f(x)= 341.24817218797057
# differential_evolution step 116: f(x)= 341.24817218797057
# differential_evolution step 117: f(x)= 341.24817218797057
# differential_evolution step 118: f(x)= 341.24817218797057
# differential_evolution step 119: f(x)= 341.24817218797057
# differential_evolution step 120: f(x)= 341.24817218797057
# differential_evolution step 121: f(x)= 341.24817218797057
# differential_evolution step 122: f(x)= 341.24817218797057
# differential_evolution step 123: f(x)= 341.24817218797057
# differential_evolution step 124: f(x)= 341.24817218797057
# differential_evolution step 125: f(x)= 341.24817218797057
# differential_evolution step 126: f(x)= 341.24817218797057
# differential_evolution step 127: f(x)= 341.24817218797057
# differential_evolution step 128: f(x)= 341.24817218797057
# differential_evolution step 129: f(x)= 341.24817218797057
# differential_evolution step 130: f(x)= 341.24817218797057
# differential_evolution step 131: f(x)= 341.24817218797057
# differential_evolution step 132: f(x)= 341.24817218797057
# differential_evolution step 133: f(x)= 341.24817218797057
# differential_evolution step 134: f(x)= 341.24817218797057
# differential_evolution step 135: f(x)= 341.24817218797057
# differential_evolution step 136: f(x)= 341.24817218797057
# differential_evolution step 137: f(x)= 341.24817218797057
# differential_evolution step 138: f(x)= 341.24817218797057
# differential_evolution step 139: f(x)= 341.24817218797057
# differential_evolution step 140: f(x)= 341.24817218797057
# differential_evolution step 141: f(x)= 341.24817218797057
# differential_evolution step 142: f(x)= 341.24817218797057
# differential_evolution step 143: f(x)= 341.24817218797057
# differential_evolution step 144: f(x)= 341.24817218797057
# differential_evolution step 145: f(x)= 341.24817218797057
# differential_evolution step 146: f(x)= 341.24817218797057
# differential_evolution step 147: f(x)= 341.24817218797057
# differential_evolution step 148: f(x)= 341.24817218797057
# differential_evolution step 149: f(x)= 341.24817218797057
# differential_evolution step 150: f(x)= 341.24817218797057
# differential_evolution step 151: f(x)= 341.24817218797057
# differential_evolution step 152: f(x)= 341.24817218797057
# differential_evolution step 153: f(x)= 341.24817218797057
# differential_evolution step 154: f(x)= 341.24817218797057
# differential_evolution step 155: f(x)= 341.24817218797057
# differential_evolution step 156: f(x)= 341.24817218797057
# differential_evolution step 157: f(x)= 341.24817218797057
# differential_evolution step 158: f(x)= 341.24817218797057
# differential_evolution step 159: f(x)= 341.24817218797057
# differential_evolution step 160: f(x)= 341.24817218797057
# differential_evolution step 161: f(x)= 341.24817218797057
# differential_evolution step 162: f(x)= 341.24817218797057
# differential_evolution step 163: f(x)= 341.24817218797057
# differential_evolution step 164: f(x)= 341.24817218797057
# differential_evolution step 165: f(x)= 341.24817218797057
# differential_evolution step 166: f(x)= 341.24817218797057
# differential_evolution step 167: f(x)= 341.24817218797057
# differential_evolution step 168: f(x)= 341.24817218797057
# differential_evolution step 169: f(x)= 341.24817218797057
# differential_evolution step 170: f(x)= 341.24817218797057
# differential_evolution step 171: f(x)= 341.24817218797057
# differential_evolution step 172: f(x)= 341.24817218797057
# differential_evolution step 173: f(x)= 341.24817218797057
# differential_evolution step 174: f(x)= 341.24817218797057
# differential_evolution step 175: f(x)= 341.24817218797057
# differential_evolution step 176: f(x)= 340.64251685607195
# differential_evolution step 177: f(x)= 340.64251685607195
# differential_evolution step 178: f(x)= 340.64251685607195
# differential_evolution step 179: f(x)= 340.64251685607195
# differential_evolution step 180: f(x)= 340.64251685607195
# differential_evolution step 181: f(x)= 340.64251685607195
# differential_evolution step 182: f(x)= 340.64251685607195
# differential_evolution step 183: f(x)= 340.64251685607195
# differential_evolution step 184: f(x)= 340.64251685607195
# differential_evolution step 185: f(x)= 340.64251685607195
# differential_evolution step 186: f(x)= 340.64251685607195
# differential_evolution step 187: f(x)= 340.64251685607195
# differential_evolution step 188: f(x)= 340.64251685607195
# differential_evolution step 189: f(x)= 340.64251685607195
# differential_evolution step 190: f(x)= 340.64251685607195
# differential_evolution step 191: f(x)= 340.64251685607195
# differential_evolution step 192: f(x)= 340.64251685607195
# differential_evolution step 193: f(x)= 340.64251685607195
# differential_evolution step 194: f(x)= 340.64251685607195
# differential_evolution step 195: f(x)= 315.4296987987031
# differential_evolution step 196: f(x)= 305.0687270354777
# differential_evolution step 197: f(x)= 305.0687270354777
# differential_evolution step 198: f(x)= 233.38795208886157
# differential_evolution step 199: f(x)= 233.38795208886157
# differential_evolution step 200: f(x)= 233.38795208886157
# differential_evolution step 201: f(x)= 233.38795208886157
# differential_evolution step 202: f(x)= 233.38795208886157
# differential_evolution step 203: f(x)= 233.38795208886157
# differential_evolution step 204: f(x)= 233.38795208886157
# differential_evolution step 205: f(x)= 233.38795208886157
# differential_evolution step 206: f(x)= 233.38795208886157
# differential_evolution step 207: f(x)= 233.38795208886157
# differential_evolution step 208: f(x)= 233.38795208886157
# differential_evolution step 209: f(x)= 233.38795208886157
# differential_evolution step 210: f(x)= 233.38795208886157
# differential_evolution step 211: f(x)= 233.38795208886157
# differential_evolution step 212: f(x)= 233.38795208886157
# differential_evolution step 213: f(x)= 233.38795208886157
# differential_evolution step 214: f(x)= 233.38795208886157
# differential_evolution step 215: f(x)= 233.38795208886157
# differential_evolution step 216: f(x)= 201.9472011574123
# differential_evolution step 217: f(x)= 201.9472011574123
# differential_evolution step 218: f(x)= 201.9472011574123
# differential_evolution step 219: f(x)= 201.9472011574123
# differential_evolution step 220: f(x)= 201.9472011574123
# differential_evolution step 221: f(x)= 201.9472011574123
# differential_evolution step 222: f(x)= 201.9472011574123
# differential_evolution step 223: f(x)= 201.9472011574123
# differential_evolution step 224: f(x)= 201.9472011574123
# differential_evolution step 225: f(x)= 201.9472011574123
# differential_evolution step 226: f(x)= 201.9472011574123
# differential_evolution step 227: f(x)= 201.9472011574123
# differential_evolution step 228: f(x)= 201.9472011574123
# differential_evolution step 229: f(x)= 201.9472011574123
# differential_evolution step 230: f(x)= 201.9472011574123
# differential_evolution step 231: f(x)= 201.9472011574123
# differential_evolution step 232: f(x)= 201.9472011574123
# differential_evolution step 233: f(x)= 201.9472011574123
# differential_evolution step 234: f(x)= 201.9472011574123
# differential_evolution step 235: f(x)= 201.9472011574123
# differential_evolution step 236: f(x)= 201.9472011574123
# differential_evolution step 237: f(x)= 201.9472011574123
# differential_evolution step 238: f(x)= 201.9472011574123
# differential_evolution step 239: f(x)= 201.9472011574123
# differential_evolution step 240: f(x)= 201.9472011574123
# differential_evolution step 241: f(x)= 201.9472011574123
# differential_evolution step 242: f(x)= 201.9472011574123
# differential_evolution step 243: f(x)= 201.9472011574123
# differential_evolution step 244: f(x)= 201.9472011574123
# differential_evolution step 245: f(x)= 201.9472011574123
# differential_evolution step 246: f(x)= 172.6567536119697
# differential_evolution step 247: f(x)= 172.6567536119697
# differential_evolution step 248: f(x)= 172.6567536119697
# differential_evolution step 249: f(x)= 172.6567536119697
# differential_evolution step 250: f(x)= 172.6567536119697
# differential_evolution step 251: f(x)= 172.6567536119697
# differential_evolution step 252: f(x)= 172.6567536119697
# differential_evolution step 253: f(x)= 172.6567536119697
# differential_evolution step 254: f(x)= 172.6567536119697
# differential_evolution step 255: f(x)= 172.6567536119697
# differential_evolution step 256: f(x)= 172.6567536119697
# differential_evolution step 257: f(x)= 172.6567536119697
# differential_evolution step 258: f(x)= 172.6567536119697
# differential_evolution step 259: f(x)= 172.6567536119697
# differential_evolution step 260: f(x)= 134.52287048015788
# differential_evolution step 261: f(x)= 134.52287048015788
# differential_evolution step 262: f(x)= 134.52287048015788
# differential_evolution step 263: f(x)= 134.52287048015788
# differential_evolution step 264: f(x)= 134.52287048015788
# differential_evolution step 265: f(x)= 134.52287048015788
# differential_evolution step 266: f(x)= 134.52287048015788
# differential_evolution step 267: f(x)= 134.52287048015788
# differential_evolution step 268: f(x)= 134.52287048015788
# differential_evolution step 269: f(x)= 134.52287048015788
# differential_evolution step 270: f(x)= 134.52287048015788
# differential_evolution step 271: f(x)= 134.52287048015788
# differential_evolution step 272: f(x)= 134.52287048015788
# differential_evolution step 273: f(x)= 134.52287048015788
# differential_evolution step 274: f(x)= 134.52287048015788
# differential_evolution step 275: f(x)= 134.52287048015788
# differential_evolution step 276: f(x)= 134.52287048015788
# differential_evolution step 277: f(x)= 134.52287048015788
# differential_evolution step 278: f(x)= 134.52287048015788
# differential_evolution step 279: f(x)= 132.90599961400474
# differential_evolution step 280: f(x)= 132.90599961400474
# differential_evolution step 281: f(x)= 132.90599961400474
# differential_evolution step 282: f(x)= 132.90599961400474
# differential_evolution step 283: f(x)= 132.90599961400474
# differential_evolution step 284: f(x)= 132.90599961400474
# differential_evolution step 285: f(x)= 132.90599961400474
# differential_evolution step 286: f(x)= 132.90599961400474
# differential_evolution step 287: f(x)= 132.90599961400474
# differential_evolution step 288: f(x)= 132.90599961400474
# differential_evolution step 289: f(x)= 132.90599961400474
# differential_evolution step 290: f(x)= 123.69308288654386
# differential_evolution step 291: f(x)= 123.69308288654386
# differential_evolution step 292: f(x)= 123.69308288654386
# differential_evolution step 293: f(x)= 123.69308288654386
# differential_evolution step 294: f(x)= 121.00542464528934
# differential_evolution step 295: f(x)= 121.00542464528934
# differential_evolution step 296: f(x)= 121.00542464528934
# differential_evolution step 297: f(x)= 121.00542464528934
# differential_evolution step 298: f(x)= 112.17872818793556
# differential_evolution step 299: f(x)= 112.17872818793556
# differential_evolution step 300: f(x)= 112.17872818793556
# differential_evolution step 301: f(x)= 112.17872818793556
# differential_evolution step 302: f(x)= 112.17872818793556
# differential_evolution step 303: f(x)= 112.17872818793556
# differential_evolution step 304: f(x)= 112.17872818793556
# differential_evolution step 305: f(x)= 112.17872818793556
# differential_evolution step 306: f(x)= 104.59418543320317
# differential_evolution step 307: f(x)= 104.59418543320317
# differential_evolution step 308: f(x)= 104.59418543320317
# differential_evolution step 309: f(x)= 104.59418543320317
# differential_evolution step 310: f(x)= 104.59418543320317
# differential_evolution step 311: f(x)= 104.59418543320317
# differential_evolution step 312: f(x)= 104.59418543320317
# differential_evolution step 313: f(x)= 104.59418543320317
# differential_evolution step 314: f(x)= 104.59418543320317
# differential_evolution step 315: f(x)= 104.59418543320317
# differential_evolution step 316: f(x)= 104.59418543320317
# differential_evolution step 317: f(x)= 104.59418543320317
# differential_evolution step 318: f(x)= 104.59418543320317
# differential_evolution step 319: f(x)= 104.59418543320317
# differential_evolution step 320: f(x)= 104.07592153260244
# differential_evolution step 321: f(x)= 104.07592153260244
# differential_evolution step 322: f(x)= 104.07592153260244
# differential_evolution step 323: f(x)= 104.07592153260244
# differential_evolution step 324: f(x)= 104.07592153260244
# differential_evolution step 325: f(x)= 104.07592153260244
# differential_evolution step 326: f(x)= 104.07592153260244
# differential_evolution step 327: f(x)= 93.92919636507871
# differential_evolution step 328: f(x)= 93.92919636507871
# differential_evolution step 329: f(x)= 93.92919636507871
# differential_evolution step 330: f(x)= 93.92919636507871
# differential_evolution step 331: f(x)= 93.92919636507871
# differential_evolution step 332: f(x)= 93.92919636507871
# differential_evolution step 333: f(x)= 93.92919636507871
# differential_evolution step 334: f(x)= 93.92919636507871
# differential_evolution step 335: f(x)= 93.92919636507871
# differential_evolution step 336: f(x)= 93.92919636507871
# differential_evolution step 337: f(x)= 89.95878653318962
# differential_evolution step 338: f(x)= 89.95878653318962
# differential_evolution step 339: f(x)= 89.95878653318962
# differential_evolution step 340: f(x)= 89.95878653318962
# differential_evolution step 341: f(x)= 89.95878653318962
# differential_evolution step 342: f(x)= 89.95878653318962
# differential_evolution step 343: f(x)= 89.95878653318962
# differential_evolution step 344: f(x)= 89.95878653318962
# differential_evolution step 345: f(x)= 89.95878653318962
# differential_evolution step 346: f(x)= 89.95878653318962
# differential_evolution step 347: f(x)= 89.95878653318962
# differential_evolution step 348: f(x)= 89.95878653318962
# differential_evolution step 349: f(x)= 89.95878653318962
# differential_evolution step 350: f(x)= 88.60640973793855
# differential_evolution step 351: f(x)= 88.31430236856711
# differential_evolution step 352: f(x)= 88.31430236856711
# differential_evolution step 353: f(x)= 88.31430236856711
# differential_evolution step 354: f(x)= 88.31430236856711
# differential_evolution step 355: f(x)= 88.31430236856711
# differential_evolution step 356: f(x)= 88.31430236856711
# differential_evolution step 357: f(x)= 88.31430236856711
# differential_evolution step 358: f(x)= 88.31430236856711
# differential_evolution step 359: f(x)= 88.31430236856711
# differential_evolution step 360: f(x)= 88.31430236856711
# differential_evolution step 361: f(x)= 88.31430236856711
# differential_evolution step 362: f(x)= 88.31430236856711
# differential_evolution step 363: f(x)= 88.31430236856711
# differential_evolution step 364: f(x)= 87.8974891301279
# differential_evolution step 365: f(x)= 87.8974891301279
# differential_evolution step 366: f(x)= 87.8974891301279
# differential_evolution step 367: f(x)= 86.33169317161462
# differential_evolution step 368: f(x)= 86.33169317161462
# differential_evolution step 369: f(x)= 86.33169317161462
# differential_evolution step 370: f(x)= 86.33169317161462
# differential_evolution step 371: f(x)= 86.33169317161462
# differential_evolution step 372: f(x)= 86.33169317161462
# differential_evolution step 373: f(x)= 86.33169317161462
# differential_evolution step 374: f(x)= 86.33169317161462
# differential_evolution step 375: f(x)= 86.33169317161462
# differential_evolution step 376: f(x)= 86.33169317161462
# differential_evolution step 377: f(x)= 86.33169317161462
# differential_evolution step 378: f(x)= 86.33169317161462
# differential_evolution step 379: f(x)= 86.33169317161462
# differential_evolution step 380: f(x)= 86.33169317161462
# differential_evolution step 381: f(x)= 86.33169317161462
# differential_evolution step 382: f(x)= 86.33169317161462
# differential_evolution step 383: f(x)= 86.33169317161462
# differential_evolution step 384: f(x)= 86.33169317161462
# differential_evolution step 385: f(x)= 86.33169317161462
# differential_evolution step 386: f(x)= 86.33169317161462
# differential_evolution step 387: f(x)= 86.33169317161462
# differential_evolution step 388: f(x)= 86.33169317161462
# differential_evolution step 389: f(x)= 86.33169317161462
# differential_evolution step 390: f(x)= 86.33169317161462
# differential_evolution step 391: f(x)= 86.33169317161462
# differential_evolution step 392: f(x)= 86.33169317161462
# differential_evolution step 393: f(x)= 86.33169317161462
# differential_evolution step 394: f(x)= 86.33169317161462
# differential_evolution step 395: f(x)= 86.33169317161462
# differential_evolution step 396: f(x)= 86.33169317161462
# differential_evolution step 397: f(x)= 86.33169317161462
# differential_evolution step 398: f(x)= 86.33169317161462
# differential_evolution step 399: f(x)= 86.33169317161462
# differential_evolution step 400: f(x)= 86.33169317161462
# differential_evolution step 401: f(x)= 86.33169317161462
# differential_evolution step 402: f(x)= 86.33169317161462
# differential_evolution step 403: f(x)= 86.33169317161462
# differential_evolution step 404: f(x)= 86.33169317161462
# differential_evolution step 405: f(x)= 86.33169317161462
# differential_evolution step 406: f(x)= 86.33169317161462
# differential_evolution step 407: f(x)= 84.89103411257035
# differential_evolution step 408: f(x)= 84.89103411257035
# differential_evolution step 409: f(x)= 83.71802181029553
# differential_evolution step 410: f(x)= 83.71802181029553
# differential_evolution step 411: f(x)= 83.71802181029553
# differential_evolution step 412: f(x)= 83.71802181029553
# differential_evolution step 413: f(x)= 83.71802181029553
# differential_evolution step 414: f(x)= 83.71802181029553
# differential_evolution step 415: f(x)= 83.71802181029553
# differential_evolution step 416: f(x)= 83.71802181029553
# differential_evolution step 417: f(x)= 83.71802181029553
# differential_evolution step 418: f(x)= 83.71802181029553
# differential_evolution step 419: f(x)= 83.71802181029553
# differential_evolution step 420: f(x)= 83.71802181029553
# differential_evolution step 421: f(x)= 83.71802181029553
# differential_evolution step 422: f(x)= 83.71802181029553
# differential_evolution step 423: f(x)= 83.71802181029553
# differential_evolution step 424: f(x)= 83.71802181029553
# differential_evolution step 425: f(x)= 83.71802181029553
# differential_evolution step 426: f(x)= 83.71802181029553
# differential_evolution step 427: f(x)= 83.71802181029553
# differential_evolution step 428: f(x)= 83.71802181029553
# differential_evolution step 429: f(x)= 81.83409100217717
# differential_evolution step 430: f(x)= 81.48871751575282
# differential_evolution step 431: f(x)= 81.48871751575282
# differential_evolution step 432: f(x)= 81.48871751575282
# differential_evolution step 433: f(x)= 79.83804178261485
# differential_evolution step 434: f(x)= 79.83804178261485
# differential_evolution step 435: f(x)= 79.83804178261485
# differential_evolution step 436: f(x)= 79.83804178261485
# differential_evolution step 437: f(x)= 79.83804178261485
# differential_evolution step 438: f(x)= 79.83804178261485
# differential_evolution step 439: f(x)= 79.83804178261485
# differential_evolution step 440: f(x)= 79.83804178261485
# differential_evolution step 441: f(x)= 79.83804178261485
# differential_evolution step 442: f(x)= 79.83804178261485
# differential_evolution step 443: f(x)= 79.83804178261485
# differential_evolution step 444: f(x)= 79.83804178261485
# differential_evolution step 445: f(x)= 79.83804178261485
# differential_evolution step 446: f(x)= 79.83804178261485
# differential_evolution step 447: f(x)= 78.44142327067166
# differential_evolution step 448: f(x)= 78.44142327067166
# differential_evolution step 449: f(x)= 78.44142327067166
# differential_evolution step 450: f(x)= 78.44142327067166
# differential_evolution step 451: f(x)= 78.44142327067166
# differential_evolution step 452: f(x)= 78.44142327067166
# differential_evolution step 453: f(x)= 73.44036603163359
# differential_evolution step 454: f(x)= 73.44036603163359
# differential_evolution step 455: f(x)= 72.36738016132027
# differential_evolution step 456: f(x)= 72.36738016132027
# differential_evolution step 457: f(x)= 72.36738016132027
# differential_evolution step 458: f(x)= 72.36738016132027
# differential_evolution step 459: f(x)= 72.36738016132027
# differential_evolution step 460: f(x)= 72.36738016132027
# differential_evolution step 461: f(x)= 72.36738016132027
# differential_evolution step 462: f(x)= 72.36738016132027
# differential_evolution step 463: f(x)= 72.36738016132027
# differential_evolution step 464: f(x)= 72.36738016132027
# differential_evolution step 465: f(x)= 72.36738016132027
# differential_evolution step 466: f(x)= 72.36738016132027
# differential_evolution step 467: f(x)= 72.36738016132027
# differential_evolution step 468: f(x)= 72.36738016132027
# differential_evolution step 469: f(x)= 72.36738016132027
# differential_evolution step 470: f(x)= 72.36738016132027
# differential_evolution step 471: f(x)= 72.36738016132027
# differential_evolution step 472: f(x)= 72.36738016132027
# differential_evolution step 473: f(x)= 72.36738016132027
# differential_evolution step 474: f(x)= 72.36738016132027
# differential_evolution step 475: f(x)= 72.36738016132027
# differential_evolution step 476: f(x)= 72.36738016132027
# differential_evolution step 477: f(x)= 72.36738016132027
# differential_evolution step 478: f(x)= 72.36738016132027
# differential_evolution step 479: f(x)= 72.36738016132027
# differential_evolution step 480: f(x)= 72.36738016132027
# differential_evolution step 481: f(x)= 72.36738016132027
# differential_evolution step 482: f(x)= 72.36738016132027
# differential_evolution step 483: f(x)= 72.36738016132027
# differential_evolution step 484: f(x)= 72.36738016132027
# differential_evolution step 485: f(x)= 72.36738016132027
# differential_evolution step 486: f(x)= 71.70814425427008
# differential_evolution step 487: f(x)= 71.70814425427008
# differential_evolution step 488: f(x)= 71.70814425427008
# differential_evolution step 489: f(x)= 71.70814425427008
# differential_evolution step 490: f(x)= 71.70814425427008
# differential_evolution step 491: f(x)= 71.70814425427008
# differential_evolution step 492: f(x)= 71.38848161972022
# differential_evolution step 493: f(x)= 71.38848161972022
# differential_evolution step 494: f(x)= 71.38848161972022
# differential_evolution step 495: f(x)= 71.38848161972022
# differential_evolution step 496: f(x)= 71.38848161972022
# differential_evolution step 497: f(x)= 70.68342903227159
# differential_evolution step 498: f(x)= 70.68342903227159
# differential_evolution step 499: f(x)= 70.68342903227159
# differential_evolution step 500: f(x)= 70.68342903227159
# differential_evolution step 501: f(x)= 70.68342903227159
# differential_evolution step 502: f(x)= 70.68342903227159
# differential_evolution step 503: f(x)= 70.68342903227159
# differential_evolution step 504: f(x)= 70.68342903227159
# differential_evolution step 505: f(x)= 70.68342903227159
# differential_evolution step 506: f(x)= 70.68342903227159
# differential_evolution step 507: f(x)= 70.68342903227159
# differential_evolution step 508: f(x)= 64.87032990684949
# differential_evolution step 509: f(x)= 64.87032990684949
# differential_evolution step 510: f(x)= 64.87032990684949
# differential_evolution step 511: f(x)= 64.87032990684949
# differential_evolution step 512: f(x)= 64.87032990684949
# differential_evolution step 513: f(x)= 64.87032990684949
# differential_evolution step 514: f(x)= 64.87032990684949
# differential_evolution step 515: f(x)= 64.87032990684949
# differential_evolution step 516: f(x)= 64.87032990684949
# differential_evolution step 517: f(x)= 64.87032990684949
# differential_evolution step 518: f(x)= 64.87032990684949
# differential_evolution step 519: f(x)= 64.87032990684949
# differential_evolution step 520: f(x)= 64.87032990684949
# differential_evolution step 521: f(x)= 64.87032990684949
# differential_evolution step 522: f(x)= 64.87032990684949
# differential_evolution step 523: f(x)= 64.87032990684949
# differential_evolution step 524: f(x)= 64.87032990684949
# differential_evolution step 525: f(x)= 64.87032990684949
# differential_evolution step 526: f(x)= 64.87032990684949
# differential_evolution step 527: f(x)= 64.87032990684949
# differential_evolution step 528: f(x)= 64.87032990684949
# differential_evolution step 529: f(x)= 64.87032990684949
# differential_evolution step 530: f(x)= 64.87032990684949
# differential_evolution step 531: f(x)= 64.87032990684949
# differential_evolution step 532: f(x)= 64.87032990684949
# differential_evolution step 533: f(x)= 64.87032990684949
# differential_evolution step 534: f(x)= 64.87032990684949
# differential_evolution step 535: f(x)= 64.87032990684949
# differential_evolution step 536: f(x)= 64.87032990684949
# differential_evolution step 537: f(x)= 64.18162471261478
# differential_evolution step 538: f(x)= 62.08195352641114
# differential_evolution step 539: f(x)= 62.08195352641114
# differential_evolution step 540: f(x)= 62.08195352641114
# differential_evolution step 541: f(x)= 62.08195352641114
# differential_evolution step 542: f(x)= 62.08195352641114
# differential_evolution step 543: f(x)= 62.08195352641114
# differential_evolution step 544: f(x)= 62.08195352641114
# differential_evolution step 545: f(x)= 62.08195352641114
# differential_evolution step 546: f(x)= 62.08195352641114
# differential_evolution step 547: f(x)= 62.08195352641114
# differential_evolution step 548: f(x)= 62.08195352641114
# differential_evolution step 549: f(x)= 62.08195352641114
# differential_evolution step 550: f(x)= 62.08195352641114
# differential_evolution step 551: f(x)= 62.08195352641114
# differential_evolution step 552: f(x)= 62.08195352641114
# differential_evolution step 553: f(x)= 62.08195352641114
# differential_evolution step 554: f(x)= 62.08195352641114
# differential_evolution step 555: f(x)= 62.08195352641114
# differential_evolution step 556: f(x)= 62.08195352641114
# differential_evolution step 557: f(x)= 62.08195352641114
# differential_evolution step 558: f(x)= 62.08195352641114
# differential_evolution step 559: f(x)= 62.08195352641114
# differential_evolution step 560: f(x)= 62.037898744943575
# differential_evolution step 561: f(x)= 55.883628228634855
# differential_evolution step 562: f(x)= 55.883628228634855
# differential_evolution step 563: f(x)= 55.883628228634855
# differential_evolution step 564: f(x)= 55.883628228634855
# differential_evolution step 565: f(x)= 55.883628228634855
# differential_evolution step 566: f(x)= 55.883628228634855
# differential_evolution step 567: f(x)= 55.883628228634855
# differential_evolution step 568: f(x)= 55.883628228634855
# differential_evolution step 569: f(x)= 55.883628228634855
# differential_evolution step 570: f(x)= 55.883628228634855
# differential_evolution step 571: f(x)= 55.883628228634855
# differential_evolution step 608: f(x)= 52.69532019940878
# differential_evolution step 609: f(x)= 52.69532019940878
# differential_evolution step 610: f(x)= 52.69532019940878
# differential_evolution step 611: f(x)= 51.67880929573424
# differential_evolution step 612: f(x)= 51.67880929573424
# differential_evolution step 613: f(x)= 51.67880929573424
# differential_evolution step 614: f(x)= 51.67880929573424
# differential_evolution step 615: f(x)= 51.67880929573424
# differential_evolution step 616: f(x)= 51.67880929573424
# differential_evolution step 617: f(x)= 51.67880929573424
# differential_evolution step 618: f(x)= 51.67880929573424
# differential_evolution step 619: f(x)= 51.67880929573424
# differential_evolution step 620: f(x)= 51.67880929573424
# differential_evolution step 621: f(x)= 51.67880929573424
# differential_evolution step 622: f(x)= 51.67880929573424
# differential_evolution step 623: f(x)= 51.67880929573424
# differential_evolution step 624: f(x)= 51.67880929573424
# differential_evolution step 625: f(x)= 51.67880929573424
# differential_evolution step 626: f(x)= 51.67880929573424
# differential_evolution step 627: f(x)= 51.67880929573424
# differential_evolution step 628: f(x)= 51.67880929573424
# differential_evolution step 629: f(x)= 51.67880929573424
# differential_evolution step 630: f(x)= 51.67880929573424
# differential_evolution step 631: f(x)= 51.67880929573424
# differential_evolution step 632: f(x)= 51.67880929573424
# differential_evolution step 633: f(x)= 51.67880929573424
# differential_evolution step 634: f(x)= 51.67880929573424
# differential_evolution step 635: f(x)= 51.67880929573424
# differential_evolution step 636: f(x)= 51.67880929573424
# differential_evolution step 637: f(x)= 51.67880929573424
# differential_evolution step 638: f(x)= 50.899749648539604
# differential_evolution step 639: f(x)= 50.899749648539604
# differential_evolution step 640: f(x)= 50.899749648539604
# differential_evolution step 641: f(x)= 50.899749648539604
# differential_evolution step 642: f(x)= 50.899749648539604
# differential_evolution step 643: f(x)= 50.899749648539604
# differential_evolution step 644: f(x)= 50.899749648539604
# differential_evolution step 645: f(x)= 50.899749648539604
# differential_evolution step 646: f(x)= 50.56232172861265
# differential_evolution step 647: f(x)= 50.56232172861265
# differential_evolution step 648: f(x)= 50.56232172861265
# differential_evolution step 649: f(x)= 50.56232172861265
# differential_evolution step 650: f(x)= 50.56232172861265
# differential_evolution step 651: f(x)= 50.56232172861265
# differential_evolution step 652: f(x)= 50.56232172861265
# differential_evolution step 653: f(x)= 50.56232172861265
# differential_evolution step 654: f(x)= 50.56232172861265
# differential_evolution step 655: f(x)= 50.56232172861265
# differential_evolution step 656: f(x)= 50.56232172861265
# differential_evolution step 657: f(x)= 49.89972593590131
# differential_evolution step 658: f(x)= 49.89972593590131
# differential_evolution step 659: f(x)= 49.89972593590131
# differential_evolution step 660: f(x)= 49.89972593590131
# differential_evolution step 661: f(x)= 49.89972593590131
# differential_evolution step 662: f(x)= 49.89972593590131
# differential_evolution step 663: f(x)= 49.89972593590131
# differential_evolution step 664: f(x)= 49.89972593590131
# differential_evolution step 665: f(x)= 49.89972593590131
# differential_evolution step 666: f(x)= 49.89972593590131
# differential_evolution step 667: f(x)= 49.89972593590131
# differential_evolution step 668: f(x)= 48.07926653105005
# differential_evolution step 669: f(x)= 48.07926653105005
# differential_evolution step 670: f(x)= 48.07926653105005
# differential_evolution step 671: f(x)= 47.97943704829661
# differential_evolution step 672: f(x)= 47.97943704829661
# differential_evolution step 673: f(x)= 47.97943704829661
# differential_evolution step 674: f(x)= 47.97943704829661
# differential_evolution step 675: f(x)= 47.97943704829661
# differential_evolution step 676: f(x)= 47.97943704829661
# differential_evolution step 677: f(x)= 47.97943704829661
# differential_evolution step 678: f(x)= 47.97943704829661
# differential_evolution step 679: f(x)= 47.97943704829661
# differential_evolution step 680: f(x)= 47.97943704829661
# differential_evolution step 681: f(x)= 47.97943704829661
# differential_evolution step 682: f(x)= 47.97943704829661
# differential_evolution step 683: f(x)= 47.97943704829661
# differential_evolution step 684: f(x)= 46.430086135265725
# differential_evolution step 685: f(x)= 46.430086135265725
# differential_evolution step 686: f(x)= 46.430086135265725
# differential_evolution step 687: f(x)= 46.430086135265725
# differential_evolution step 688: f(x)= 46.430086135265725
# differential_evolution step 689: f(x)= 46.26809894297795
# differential_evolution step 690: f(x)= 46.26809894297795
# differential_evolution step 691: f(x)= 46.26809894297795
# differential_evolution step 692: f(x)= 46.26809894297795
# differential_evolution step 693: f(x)= 46.067999443109706
# differential_evolution step 694: f(x)= 46.067999443109706
# differential_evolution step 695: f(x)= 46.067999443109706
# differential_evolution step 696: f(x)= 46.067999443109706
# differential_evolution step 697: f(x)= 46.067999443109706
# differential_evolution step 698: f(x)= 43.38778663004722
# differential_evolution step 699: f(x)= 43.38778663004722
# differential_evolution step 700: f(x)= 43.38778663004722
# differential_evolution step 701: f(x)= 43.38778663004722
# differential_evolution step 702: f(x)= 40.7900458671794
# differential_evolution step 703: f(x)= 40.7900458671794
# differential_evolution step 704: f(x)= 40.7900458671794
# differential_evolution step 705: f(x)= 40.7900458671794
# differential_evolution step 706: f(x)= 40.7900458671794
# differential_evolution step 707: f(x)= 40.7900458671794
# differential_evolution step 708: f(x)= 40.7900458671794
# differential_evolution step 709: f(x)= 40.7900458671794
# differential_evolution step 710: f(x)= 40.7900458671794
# differential_evolution step 711: f(x)= 40.7900458671794
# differential_evolution step 712: f(x)= 40.7900458671794
# differential_evolution step 713: f(x)= 40.357459497196274
# differential_evolution step 714: f(x)= 40.357459497196274
# differential_evolution step 715: f(x)= 40.357459497196274
# differential_evolution step 716: f(x)= 40.357459497196274
# differential_evolution step 717: f(x)= 39.84581696201874
# differential_evolution step 718: f(x)= 39.84581696201874
# differential_evolution step 719: f(x)= 39.84581696201874
# differential_evolution step 720: f(x)= 39.48124654024588
# differential_evolution step 721: f(x)= 39.48124654024588
# differential_evolution step 722: f(x)= 39.48124654024588
# differential_evolution step 723: f(x)= 39.48124654024588
# differential_evolution step 724: f(x)= 39.48124654024588
# differential_evolution step 725: f(x)= 39.48124654024588
# differential_evolution step 726: f(x)= 39.48124654024588
# differential_evolution step 727: f(x)= 39.48124654024588
# differential_evolution step 728: f(x)= 39.48124654024588
# differential_evolution step 729: f(x)= 39.48124654024588
# differential_evolution step 730: f(x)= 39.48124654024588
# differential_evolution step 731: f(x)= 39.48124654024588
# differential_evolution step 732: f(x)= 39.48124654024588
# differential_evolution step 733: f(x)= 39.48124654024588
# differential_evolution step 734: f(x)= 39.48124654024588
# differential_evolution step 735: f(x)= 39.48124654024588
# differential_evolution step 736: f(x)= 39.48124654024588
# differential_evolution step 737: f(x)= 39.48124654024588
# differential_evolution step 738: f(x)= 39.48124654024588
# differential_evolution step 739: f(x)= 39.48124654024588
# differential_evolution step 740: f(x)= 39.48124654024588
# differential_evolution step 741: f(x)= 39.48124654024588
# differential_evolution step 742: f(x)= 39.48124654024588
# differential_evolution step 743: f(x)= 39.48124654024588
# differential_evolution step 744: f(x)= 39.48124654024588
# differential_evolution step 745: f(x)= 39.48124654024588
# differential_evolution step 746: f(x)= 36.81119871960166
# differential_evolution step 747: f(x)= 36.48564155730064
# differential_evolution step 748: f(x)= 36.48564155730064
# differential_evolution step 749: f(x)= 36.48564155730064
# differential_evolution step 750: f(x)= 36.48564155730064
# differential_evolution step 751: f(x)= 36.48564155730064
# differential_evolution step 752: f(x)= 36.48564155730064
# differential_evolution step 753: f(x)= 36.48564155730064
# differential_evolution step 754: f(x)= 36.48564155730064
# differential_evolution step 755: f(x)= 36.48564155730064
# differential_evolution step 756: f(x)= 36.337742684244496
# differential_evolution step 757: f(x)= 36.337742684244496
# differential_evolution step 758: f(x)= 35.43536600614119
# differential_evolution step 759: f(x)= 31.513874467308874
# differential_evolution step 760: f(x)= 31.513874467308874
# differential_evolution step 761: f(x)= 31.513874467308874
# differential_evolution step 762: f(x)= 31.513874467308874
# differential_evolution step 763: f(x)= 31.513874467308874
# differential_evolution step 764: f(x)= 31.101062334271564
# differential_evolution step 765: f(x)= 31.101062334271564
# differential_evolution step 766: f(x)= 31.101062334271564
# differential_evolution step 767: f(x)= 31.101062334271564
# differential_evolution step 768: f(x)= 31.101062334271564
# differential_evolution step 769: f(x)= 31.101062334271564
# differential_evolution step 770: f(x)= 31.101062334271564
# differential_evolution step 771: f(x)= 31.101062334271564
# differential_evolution step 772: f(x)= 31.101062334271564
# differential_evolution step 773: f(x)= 31.101062334271564
# differential_evolution step 774: f(x)= 31.101062334271564
# differential_evolution step 775: f(x)= 31.101062334271564
# differential_evolution step 776: f(x)= 31.101062334271564
# differential_evolution step 777: f(x)= 31.101062334271564
# differential_evolution step 778: f(x)= 31.101062334271564
# differential_evolution step 779: f(x)= 31.101062334271564
# differential_evolution step 780: f(x)= 31.101062334271564
# differential_evolution step 781: f(x)= 31.101062334271564
# differential_evolution step 782: f(x)= 31.101062334271564
# differential_evolution step 783: f(x)= 31.101062334271564
# differential_evolution step 784: f(x)= 31.101062334271564
# differential_evolution step 785: f(x)= 31.101062334271564
# differential_evolution step 786: f(x)= 31.101062334271564
# differential_evolution step 787: f(x)= 31.101062334271564
# differential_evolution step 788: f(x)= 31.101062334271564
# differential_evolution step 789: f(x)= 31.101062334271564
# differential_evolution step 790: f(x)= 31.101062334271564
# differential_evolution step 791: f(x)= 31.101062334271564
# differential_evolution step 792: f(x)= 31.101062334271564
# differential_evolution step 793: f(x)= 31.101062334271564
# differential_evolution step 794: f(x)= 31.101062334271564
# differential_evolution step 795: f(x)= 30.548375678989007
# differential_evolution step 796: f(x)= 30.548375678989007
# differential_evolution step 797: f(x)= 30.38013050693627
# differential_evolution step 798: f(x)= 30.38013050693627
# differential_evolution step 799: f(x)= 30.38013050693627
# differential_evolution step 800: f(x)= 30.38013050693627
# differential_evolution step 801: f(x)= 30.38013050693627
# differential_evolution step 802: f(x)= 30.38013050693627
# differential_evolution step 803: f(x)= 30.38013050693627
# differential_evolution step 804: f(x)= 30.38013050693627
# differential_evolution step 805: f(x)= 30.38013050693627
# differential_evolution step 806: f(x)= 27.420837168573243
# differential_evolution step 807: f(x)= 27.420837168573243
# differential_evolution step 808: f(x)= 27.420837168573243
# differential_evolution step 809: f(x)= 27.420837168573243
# differential_evolution step 810: f(x)= 27.420837168573243
# differential_evolution step 811: f(x)= 25.73950006816507
# differential_evolution step 812: f(x)= 25.73950006816507
# differential_evolution step 813: f(x)= 25.73950006816507
# differential_evolution step 814: f(x)= 25.73950006816507
# differential_evolution step 815: f(x)= 25.73950006816507
# differential_evolution step 816: f(x)= 25.73950006816507
# differential_evolution step 817: f(x)= 25.73950006816507
# differential_evolution step 818: f(x)= 25.73950006816507
# differential_evolution step 819: f(x)= 25.73950006816507
# differential_evolution step 820: f(x)= 25.73950006816507
# differential_evolution step 821: f(x)= 25.73950006816507
# differential_evolution step 822: f(x)= 25.73950006816507
# differential_evolution step 823: f(x)= 25.73950006816507
# differential_evolution step 824: f(x)= 25.73950006816507
# differential_evolution step 825: f(x)= 25.73950006816507
# differential_evolution step 826: f(x)= 25.73950006816507
# differential_evolution step 827: f(x)= 25.73950006816507
# differential_evolution step 828: f(x)= 25.73950006816507
# differential_evolution step 829: f(x)= 25.73950006816507
# differential_evolution step 830: f(x)= 25.73950006816507
# differential_evolution step 831: f(x)= 25.73950006816507
# differential_evolution step 832: f(x)= 25.73950006816507
# differential_evolution step 833: f(x)= 25.73950006816507
# differential_evolution step 834: f(x)= 25.73950006816507
# differential_evolution step 835: f(x)= 25.73950006816507
# differential_evolution step 836: f(x)= 25.73950006816507
# differential_evolution step 837: f(x)= 25.73950006816507
# differential_evolution step 838: f(x)= 25.73950006816507
# differential_evolution step 839: f(x)= 25.73950006816507
# differential_evolution step 840: f(x)= 25.73950006816507
# differential_evolution step 841: f(x)= 25.73950006816507
# differential_evolution step 842: f(x)= 25.73950006816507
# differential_evolution step 843: f(x)= 25.73950006816507
# differential_evolution step 844: f(x)= 25.73950006816507
# differential_evolution step 845: f(x)= 25.73950006816507
# differential_evolution step 846: f(x)= 25.73950006816507
# differential_evolution step 847: f(x)= 25.73950006816507
# differential_evolution step 848: f(x)= 25.73950006816507
# differential_evolution step 849: f(x)= 25.73950006816507
# differential_evolution step 850: f(x)= 25.73950006816507
# differential_evolution step 851: f(x)= 25.73950006816507
# differential_evolution step 852: f(x)= 25.73950006816507
# differential_evolution step 853: f(x)= 25.73950006816507
# differential_evolution step 854: f(x)= 25.73950006816507
# differential_evolution step 855: f(x)= 25.73950006816507
# differential_evolution step 856: f(x)= 24.867503745955627
# differential_evolution step 857: f(x)= 24.867503745955627
# differential_evolution step 858: f(x)= 24.867503745955627
# differential_evolution step 859: f(x)= 23.479347065587213
# differential_evolution step 860: f(x)= 23.479347065587213
# differential_evolution step 861: f(x)= 23.479347065587213
# differential_evolution step 862: f(x)= 23.479347065587213
# differential_evolution step 863: f(x)= 23.479347065587213
# differential_evolution step 864: f(x)= 23.479347065587213
# differential_evolution step 865: f(x)= 23.479347065587213
# differential_evolution step 866: f(x)= 23.479347065587213
# differential_evolution step 867: f(x)= 23.479347065587213
# differential_evolution step 868: f(x)= 23.479347065587213
# differential_evolution step 869: f(x)= 23.479347065587213
# differential_evolution step 870: f(x)= 23.479347065587213
# differential_evolution step 871: f(x)= 23.479347065587213
# differential_evolution step 872: f(x)= 23.479347065587213
# differential_evolution step 873: f(x)= 23.479347065587213
# differential_evolution step 874: f(x)= 23.479347065587213
# differential_evolution step 875: f(x)= 23.421314014172058
# differential_evolution step 876: f(x)= 23.421314014172058
# differential_evolution step 877: f(x)= 23.421314014172058
# differential_evolution step 878: f(x)= 23.421314014172058
# differential_evolution step 879: f(x)= 23.421314014172058
# differential_evolution step 880: f(x)= 23.421314014172058
# differential_evolution step 881: f(x)= 23.421314014172058
# differential_evolution step 882: f(x)= 23.421314014172058
# differential_evolution step 883: f(x)= 23.421314014172058
# differential_evolution step 884: f(x)= 23.421314014172058
# differential_evolution step 885: f(x)= 23.421314014172058
# differential_evolution step 886: f(x)= 23.421314014172058
# differential_evolution step 887: f(x)= 23.421314014172058
# differential_evolution step 888: f(x)= 23.421314014172058
# differential_evolution step 889: f(x)= 23.421314014172058
# differential_evolution step 890: f(x)= 23.421314014172058
# differential_evolution step 891: f(x)= 23.421314014172058
# differential_evolution step 892: f(x)= 23.421314014172058
# differential_evolution step 893: f(x)= 23.421314014172058
# differential_evolution step 894: f(x)= 23.421314014172058
# differential_evolution step 895: f(x)= 23.421314014172058
# differential_evolution step 896: f(x)= 23.421314014172058
# differential_evolution step 897: f(x)= 23.421314014172058
# differential_evolution step 898: f(x)= 23.421314014172058
# differential_evolution step 899: f(x)= 23.421314014172058
# differential_evolution step 900: f(x)= 23.421314014172058
# differential_evolution step 901: f(x)= 23.421314014172058
# differential_evolution step 902: f(x)= 23.421314014172058
# differential_evolution step 903: f(x)= 23.421314014172058
# differential_evolution step 904: f(x)= 23.421314014172058
# differential_evolution step 905: f(x)= 23.421314014172058
# differential_evolution step 906: f(x)= 23.421314014172058
# differential_evolution step 907: f(x)= 21.44718922290127
# differential_evolution step 908: f(x)= 21.44718922290127
# differential_evolution step 909: f(x)= 21.44718922290127
# differential_evolution step 910: f(x)= 21.44718922290127
# differential_evolution step 911: f(x)= 21.44718922290127
# differential_evolution step 912: f(x)= 21.07808446614115
# differential_evolution step 913: f(x)= 21.07808446614115
# differential_evolution step 914: f(x)= 21.07808446614115
# differential_evolution step 915: f(x)= 21.07808446614115
# differential_evolution step 916: f(x)= 21.07808446614115
# differential_evolution step 917: f(x)= 21.07808446614115
# differential_evolution step 918: f(x)= 21.07808446614115
# differential_evolution step 919: f(x)= 21.07808446614115
# differential_evolution step 920: f(x)= 21.07808446614115
# differential_evolution step 921: f(x)= 21.07808446614115
# differential_evolution step 922: f(x)= 21.07808446614115
# differential_evolution step 923: f(x)= 21.07808446614115
# differential_evolution step 924: f(x)= 21.07808446614115
# differential_evolution step 925: f(x)= 21.07808446614115
# differential_evolution step 926: f(x)= 21.07808446614115
# differential_evolution step 927: f(x)= 21.07808446614115
# differential_evolution step 928: f(x)= 21.07808446614115
# differential_evolution step 929: f(x)= 21.07808446614115
# differential_evolution step 930: f(x)= 21.07808446614115
# differential_evolution step 931: f(x)= 21.07808446614115
# differential_evolution step 932: f(x)= 19.641343195686293
# differential_evolution step 933: f(x)= 19.641343195686293
# differential_evolution step 934: f(x)= 19.641343195686293
# differential_evolution step 935: f(x)= 17.839994436224796
# differential_evolution step 936: f(x)= 17.839994436224796
# differential_evolution step 937: f(x)= 17.839994436224796
# differential_evolution step 938: f(x)= 17.839994436224796
# differential_evolution step 939: f(x)= 17.839994436224796
# differential_evolution step 940: f(x)= 17.839994436224796
# differential_evolution step 941: f(x)= 17.839994436224796
# differential_evolution step 942: f(x)= 17.839994436224796
# differential_evolution step 943: f(x)= 17.839994436224796
# differential_evolution step 944: f(x)= 17.839994436224796
# differential_evolution step 945: f(x)= 17.839994436224796
# differential_evolution step 946: f(x)= 17.839994436224796
# differential_evolution step 947: f(x)= 17.839994436224796
# differential_evolution step 948: f(x)= 17.839994436224796
# differential_evolution step 949: f(x)= 17.839994436224796
# differential_evolution step 950: f(x)= 17.839994436224796
# differential_evolution step 951: f(x)= 17.839994436224796
# differential_evolution step 952: f(x)= 17.839994436224796
# differential_evolution step 953: f(x)= 17.839994436224796
# differential_evolution step 954: f(x)= 17.839994436224796
# differential_evolution step 955: f(x)= 17.839994436224796
# differential_evolution step 956: f(x)= 17.839994436224796
# differential_evolution step 957: f(x)= 17.839994436224796
# differential_evolution step 958: f(x)= 17.839994436224796
# differential_evolution step 959: f(x)= 17.2693030603513
# differential_evolution step 960: f(x)= 17.2693030603513
# differential_evolution step 961: f(x)= 17.2693030603513
# differential_evolution step 962: f(x)= 17.2693030603513
# differential_evolution step 963: f(x)= 17.2693030603513
# differential_evolution step 964: f(x)= 17.2693030603513
# differential_evolution step 965: f(x)= 17.2693030603513
# differential_evolution step 966: f(x)= 17.2693030603513
# differential_evolution step 967: f(x)= 17.2693030603513
# differential_evolution step 968: f(x)= 17.2693030603513
# differential_evolution step 969: f(x)= 17.2693030603513
# differential_evolution step 970: f(x)= 16.215986645182518
# differential_evolution step 971: f(x)= 16.215986645182518
# differential_evolution step 972: f(x)= 16.215986645182518
# differential_evolution step 973: f(x)= 16.215986645182518
# differential_evolution step 974: f(x)= 16.215986645182518
# differential_evolution step 975: f(x)= 16.215986645182518
# differential_evolution step 976: f(x)= 15.99066399719684
# differential_evolution step 977: f(x)= 15.99066399719684
# differential_evolution step 978: f(x)= 15.804122659916311
# differential_evolution step 979: f(x)= 15.272185673561493
# differential_evolution step 980: f(x)= 15.272185673561493
# differential_evolution step 981: f(x)= 15.272185673561493
# differential_evolution step 982: f(x)= 15.08989561355717
# differential_evolution step 983: f(x)= 15.08989561355717
# differential_evolution step 984: f(x)= 15.08989561355717
# differential_evolution step 985: f(x)= 14.660244464477442
# differential_evolution step 986: f(x)= 14.660244464477442
# differential_evolution step 987: f(x)= 14.660244464477442
# differential_evolution step 988: f(x)= 14.660244464477442
# differential_evolution step 989: f(x)= 14.57247662776073
# differential_evolution step 990: f(x)= 14.57247662776073
# differential_evolution step 991: f(x)= 14.57247662776073
# differential_evolution step 992: f(x)= 14.57247662776073
# differential_evolution step 993: f(x)= 14.57247662776073
# differential_evolution step 994: f(x)= 14.57247662776073
# differential_evolution step 995: f(x)= 14.57247662776073
# differential_evolution step 996: f(x)= 14.57247662776073
# differential_evolution step 997: f(x)= 14.57247662776073
# differential_evolution step 998: f(x)= 14.57247662776073
# differential_evolution step 999: f(x)= 14.57247662776073
# differential_evolution step 1000: f(x)= 14.57247662776073
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_1328\111436280.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution: [ 7.32970328  6.43914683  1.13109586 62.13421576  8.93779336  2.26507211
#   1.04515968 51.81180094  7.27882615  2.58045433  1.10853014 59.34717829
#   3.57772526 13.60984084  0.90956082 47.76543553]
# Chi quadro minimo: 14.57247662776073

# %%
# Plots:
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_1328\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_1328\2283290254.py:10: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=13.0618, r_e=5.0540, n=0.8850, x_0=61.3980
# Sérsic 2: I_e=17.0616, r_e=1.6501, n=0.5632, x_0=51.7532
# Sérsic 3: I_e=0.0265, r_e=90.4695, n=4.9594, x_0=58.8702
# Sérsic 4: I_e=2.8582, r_e=13.7381, n=1.0713, x_0=47.1110
# [1.21659386e+00 1.70556032e-01 4.86099372e-02 1.93700372e-01
#  4.81904787e+00 3.04323073e-01 2.22341220e-01 6.15527917e-02
#  1.29705080e-01 2.71083040e+02 5.91445672e+00 2.75553945e-04
#  3.20434657e-01 6.19461956e-01 5.65884050e-02 5.33680317e-01]
# 49.377822055477566
# 87.93203892294744 49.377822055477566 123.06054503128703 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, [aic[0], aic[1], aic[2], aic[3]], marker = 'o')
plt.savefig('AIC_vs_N', bbox_inches='tight')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, [bic[0], bic[1], bic[2], bic[3]], marker = 'o')
plt.savefig('BIC_vs_N', bbox_inches='tight')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, [red_chi[0], red_chi[1], red_chi[2], red_chi[3]], marker = 'o')
plt.savefig('Reduced_chi_vs_N', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log', bbox_inches='tight')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log', bbox_inches='tight')
