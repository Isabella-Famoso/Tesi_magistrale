# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32

# %%
image_cut = image[70:170, 0:1890]
image_error_cut = image_error[70:170, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')

# %%
z = 0.00328
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/PSF/Real_seeing_NGC3773.txt")
sigmas = seeing / 2.35
print(sigmas)
# Out:
# [1.01016511 1.12309039 1.00840577 0.99664427 1.1197505  1.01319149]

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Propag_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (43, 45),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62), 
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
n_component = 3
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 9178.584421796335
# differential_evolution step 2: f(x)= 5134.595807169071
# differential_evolution step 3: f(x)= 5134.595807169071
# differential_evolution step 4: f(x)= 2790.631497785669
# differential_evolution step 5: f(x)= 1425.0970100072896
# differential_evolution step 6: f(x)= 1425.0970100072896
# differential_evolution step 7: f(x)= 1425.0970100072896
# differential_evolution step 8: f(x)= 1425.0970100072896
# differential_evolution step 9: f(x)= 1425.0970100072896
# differential_evolution step 10: f(x)= 1354.1339409283376
# differential_evolution step 11: f(x)= 1354.1339409283376
# differential_evolution step 12: f(x)= 1354.1339409283376
# differential_evolution step 13: f(x)= 794.0883958727941
# differential_evolution step 14: f(x)= 794.0883958727941
# differential_evolution step 15: f(x)= 382.33245907330786
# differential_evolution step 16: f(x)= 382.33245907330786
# differential_evolution step 17: f(x)= 382.33245907330786
# differential_evolution step 18: f(x)= 382.33245907330786
# differential_evolution step 19: f(x)= 382.33245907330786
# differential_evolution step 20: f(x)= 382.33245907330786
# differential_evolution step 21: f(x)= 382.33245907330786
# differential_evolution step 22: f(x)= 382.33245907330786
# differential_evolution step 23: f(x)= 382.33245907330786
# differential_evolution step 24: f(x)= 382.33245907330786
# differential_evolution step 25: f(x)= 382.33245907330786
# differential_evolution step 26: f(x)= 382.33245907330786
# differential_evolution step 27: f(x)= 382.33245907330786
# differential_evolution step 28: f(x)= 309.78644500928533
# differential_evolution step 29: f(x)= 234.86170379300034
# differential_evolution step 30: f(x)= 234.86170379300034
# differential_evolution step 31: f(x)= 234.86170379300034
# differential_evolution step 32: f(x)= 234.86170379300034
# differential_evolution step 33: f(x)= 224.9334229108721
# differential_evolution step 34: f(x)= 224.9334229108721
# differential_evolution step 35: f(x)= 224.9334229108721
# differential_evolution step 36: f(x)= 153.7885427876991
# differential_evolution step 37: f(x)= 153.7885427876991
# differential_evolution step 38: f(x)= 153.7885427876991
# differential_evolution step 39: f(x)= 153.7885427876991
# differential_evolution step 40: f(x)= 153.7885427876991
# differential_evolution step 41: f(x)= 153.7885427876991
# differential_evolution step 42: f(x)= 146.65819643220547
# differential_evolution step 43: f(x)= 146.65819643220547
# differential_evolution step 44: f(x)= 146.65819643220547
# differential_evolution step 45: f(x)= 146.65819643220547
# differential_evolution step 46: f(x)= 146.65819643220547
# differential_evolution step 47: f(x)= 146.65819643220547
# differential_evolution step 48: f(x)= 146.65819643220547
# differential_evolution step 49: f(x)= 146.65819643220547
# differential_evolution step 50: f(x)= 146.65819643220547
# differential_evolution step 51: f(x)= 146.65819643220547
# differential_evolution step 52: f(x)= 134.7998985775734
# differential_evolution step 53: f(x)= 134.7998985775734
# differential_evolution step 54: f(x)= 134.75423178736904
# differential_evolution step 55: f(x)= 134.75423178736904
# differential_evolution step 56: f(x)= 134.75423178736904
# differential_evolution step 57: f(x)= 134.75423178736904
# differential_evolution step 58: f(x)= 134.75423178736904
# differential_evolution step 59: f(x)= 134.75423178736904
# differential_evolution step 60: f(x)= 134.75423178736904
# differential_evolution step 61: f(x)= 134.75423178736904
# differential_evolution step 62: f(x)= 130.52087326956703
# differential_evolution step 63: f(x)= 129.17654439267133
# differential_evolution step 64: f(x)= 122.02062687701219
# differential_evolution step 65: f(x)= 122.02062687701219
# differential_evolution step 66: f(x)= 122.02062687701219
# differential_evolution step 67: f(x)= 122.02062687701219
# differential_evolution step 68: f(x)= 121.95976332669137
# differential_evolution step 69: f(x)= 120.29410433839179
# differential_evolution step 70: f(x)= 120.29410433839179
# differential_evolution step 71: f(x)= 118.95435816378067
# differential_evolution step 72: f(x)= 118.95435816378067
# differential_evolution step 73: f(x)= 118.95435816378067
# differential_evolution step 74: f(x)= 118.95435816378067
# differential_evolution step 75: f(x)= 118.95435816378067
# differential_evolution step 76: f(x)= 118.95435816378067
# differential_evolution step 77: f(x)= 118.95435816378067
# differential_evolution step 78: f(x)= 118.5457837195419
# differential_evolution step 79: f(x)= 118.5457837195419
# differential_evolution step 80: f(x)= 114.66243332721122
# differential_evolution step 81: f(x)= 114.66243332721122
# differential_evolution step 82: f(x)= 114.66243332721122
# differential_evolution step 83: f(x)= 114.66243332721122
# differential_evolution step 84: f(x)= 114.66243332721122
# differential_evolution step 85: f(x)= 114.66243332721122
# differential_evolution step 86: f(x)= 114.66243332721122
# differential_evolution step 87: f(x)= 114.66243332721122
# differential_evolution step 88: f(x)= 114.66243332721122
# differential_evolution step 89: f(x)= 114.66243332721122
# differential_evolution step 90: f(x)= 114.66243332721122
# differential_evolution step 91: f(x)= 113.27588318475019
# differential_evolution step 92: f(x)= 113.27588318475019
# differential_evolution step 93: f(x)= 113.27588318475019
# differential_evolution step 94: f(x)= 113.27588318475019
# differential_evolution step 95: f(x)= 113.27588318475019
# differential_evolution step 96: f(x)= 113.27588318475019
# differential_evolution step 97: f(x)= 113.27588318475019
# differential_evolution step 98: f(x)= 113.27588318475019
# differential_evolution step 99: f(x)= 113.27588318475019
# differential_evolution step 100: f(x)= 113.27588318475019
# differential_evolution step 101: f(x)= 113.27588318475019
# differential_evolution step 102: f(x)= 113.27588318475019
# differential_evolution step 103: f(x)= 113.27588318475019
# differential_evolution step 104: f(x)= 113.27588318475019
# differential_evolution step 105: f(x)= 113.27588318475019
# differential_evolution step 106: f(x)= 113.27588318475019
# differential_evolution step 107: f(x)= 113.27588318475019
# differential_evolution step 108: f(x)= 113.27588318475019
# differential_evolution step 109: f(x)= 113.27588318475019
# differential_evolution step 110: f(x)= 113.27588318475019
# differential_evolution step 111: f(x)= 113.27588318475019
# differential_evolution step 112: f(x)= 111.74905572579026
# differential_evolution step 113: f(x)= 111.74905572579026
# differential_evolution step 114: f(x)= 111.74905572579026
# differential_evolution step 115: f(x)= 111.74905572579026
# differential_evolution step 116: f(x)= 111.74905572579026
# differential_evolution step 117: f(x)= 111.06653834860204
# differential_evolution step 118: f(x)= 111.06653834860204
# differential_evolution step 119: f(x)= 111.06653834860204
# differential_evolution step 120: f(x)= 111.06653834860204
# differential_evolution step 121: f(x)= 111.06653834860204
# differential_evolution step 122: f(x)= 111.06653834860204
# differential_evolution step 123: f(x)= 110.85358374968635
# differential_evolution step 124: f(x)= 110.85358374968635
# differential_evolution step 125: f(x)= 110.85358374968635
# differential_evolution step 126: f(x)= 110.47489830566514
# differential_evolution step 127: f(x)= 110.47489830566514
# differential_evolution step 128: f(x)= 110.47489830566514
# differential_evolution step 129: f(x)= 110.47489830566514
# differential_evolution step 130: f(x)= 110.47489830566514
# differential_evolution step 131: f(x)= 110.47489830566514
# differential_evolution step 132: f(x)= 110.47489830566514
# differential_evolution step 133: f(x)= 110.47489830566514
# differential_evolution step 134: f(x)= 109.31559166219763
# differential_evolution step 135: f(x)= 109.31559166219763
# differential_evolution step 136: f(x)= 109.31559166219763
# differential_evolution step 137: f(x)= 109.31559166219763
# differential_evolution step 138: f(x)= 109.31559166219763
# differential_evolution step 139: f(x)= 109.31559166219763
# differential_evolution step 140: f(x)= 109.31559166219763
# differential_evolution step 141: f(x)= 109.31559166219763
# differential_evolution step 142: f(x)= 109.31559166219763
# differential_evolution step 143: f(x)= 109.31559166219763
# differential_evolution step 144: f(x)= 109.31559166219763
# differential_evolution step 145: f(x)= 109.31559166219763
# differential_evolution step 146: f(x)= 109.31559166219763
# differential_evolution step 147: f(x)= 109.31559166219763
# differential_evolution step 148: f(x)= 109.31559166219763
# differential_evolution step 149: f(x)= 109.31559166219763
# differential_evolution step 150: f(x)= 109.31559166219763
# differential_evolution step 151: f(x)= 109.31559166219763
# differential_evolution step 152: f(x)= 109.31559166219763
# differential_evolution step 153: f(x)= 109.31559166219763
# differential_evolution step 154: f(x)= 109.31559166219763
# differential_evolution step 155: f(x)= 109.31559166219763
# differential_evolution step 156: f(x)= 109.31559166219763
# differential_evolution step 157: f(x)= 109.31559166219763
# differential_evolution step 158: f(x)= 109.31559166219763
# differential_evolution step 159: f(x)= 109.31559166219763
# differential_evolution step 160: f(x)= 109.31559166219763
# differential_evolution step 161: f(x)= 109.12561675710097
# differential_evolution step 162: f(x)= 108.96072550705924
# differential_evolution step 163: f(x)= 108.96072550705924
# differential_evolution step 164: f(x)= 108.96072550705924
# differential_evolution step 165: f(x)= 108.96072550705924
# differential_evolution step 166: f(x)= 108.96072550705924
# differential_evolution step 167: f(x)= 108.96072550705924
# differential_evolution step 168: f(x)= 108.96072550705924
# differential_evolution step 169: f(x)= 108.96072550705924
# differential_evolution step 170: f(x)= 108.96072550705924
# differential_evolution step 171: f(x)= 108.96072550705924
# differential_evolution step 172: f(x)= 108.96072550705924
# differential_evolution step 173: f(x)= 108.96072550705924
# differential_evolution step 174: f(x)= 108.96072550705924
# differential_evolution step 175: f(x)= 108.96072550705924
# differential_evolution step 176: f(x)= 108.96072550705924
# differential_evolution step 177: f(x)= 108.96072550705924
# differential_evolution step 178: f(x)= 108.96072550705924
# differential_evolution step 179: f(x)= 108.96072550705924
# differential_evolution step 180: f(x)= 108.96072550705924
# differential_evolution step 181: f(x)= 108.96072550705924
# differential_evolution step 182: f(x)= 108.96072550705924
# differential_evolution step 183: f(x)= 108.96072550705924
# differential_evolution step 184: f(x)= 108.96072550705924
# differential_evolution step 185: f(x)= 108.92424478405586
# differential_evolution step 186: f(x)= 108.826883926008
# differential_evolution step 187: f(x)= 108.80874044279656
# differential_evolution step 188: f(x)= 108.80874044279656
# differential_evolution step 189: f(x)= 108.75710502607389
# differential_evolution step 190: f(x)= 108.68990411647009
# differential_evolution step 191: f(x)= 108.49283552810758
# differential_evolution step 192: f(x)= 108.49283552810758
# differential_evolution step 193: f(x)= 108.49283552810758
# differential_evolution step 194: f(x)= 108.49283552810758
# differential_evolution step 195: f(x)= 108.49283552810758
# differential_evolution step 196: f(x)= 108.49283552810758
# differential_evolution step 197: f(x)= 108.4350888043771
# differential_evolution step 198: f(x)= 108.4350888043771
# differential_evolution step 199: f(x)= 108.4350888043771
# differential_evolution step 200: f(x)= 108.4350888043771
# differential_evolution step 201: f(x)= 108.33600955129673
# differential_evolution step 202: f(x)= 108.33600955129673
# differential_evolution step 203: f(x)= 108.33600955129673
# differential_evolution step 204: f(x)= 108.33600955129673
# differential_evolution step 205: f(x)= 108.33600955129673
# differential_evolution step 206: f(x)= 108.21080970513233
# differential_evolution step 207: f(x)= 108.21080970513233
# differential_evolution step 208: f(x)= 108.21080970513233
# differential_evolution step 209: f(x)= 108.21080970513233
# differential_evolution step 210: f(x)= 108.21080970513233
# differential_evolution step 211: f(x)= 108.21080970513233
# differential_evolution step 212: f(x)= 108.21080970513233
# differential_evolution step 213: f(x)= 108.10444085522202
# differential_evolution step 214: f(x)= 108.10444085522202
# differential_evolution step 215: f(x)= 108.10444085522202
# differential_evolution step 216: f(x)= 108.10444085522202
# differential_evolution step 217: f(x)= 108.10444085522202
# differential_evolution step 218: f(x)= 108.10444085522202
# differential_evolution step 219: f(x)= 108.10444085522202
# differential_evolution step 220: f(x)= 108.10444085522202
# differential_evolution step 221: f(x)= 108.10444085522202
# differential_evolution step 222: f(x)= 108.10444085522202
# differential_evolution step 223: f(x)= 108.10444085522202
# differential_evolution step 224: f(x)= 108.10444085522202
# differential_evolution step 225: f(x)= 108.09024227243913
# differential_evolution step 226: f(x)= 108.09024227243913
# differential_evolution step 227: f(x)= 108.09024227243913
# differential_evolution step 228: f(x)= 108.09024227243913
# differential_evolution step 229: f(x)= 108.09024227243913
# differential_evolution step 230: f(x)= 108.09024227243913
# differential_evolution step 231: f(x)= 108.09024227243913
# differential_evolution step 232: f(x)= 107.8923935347018
# differential_evolution step 233: f(x)= 107.8923935347018
# differential_evolution step 234: f(x)= 107.8923935347018
# differential_evolution step 235: f(x)= 107.8923935347018
# differential_evolution step 236: f(x)= 107.8923935347018
# differential_evolution step 237: f(x)= 107.8923935347018
# differential_evolution step 238: f(x)= 107.8923935347018
# differential_evolution step 239: f(x)= 107.8923935347018
# differential_evolution step 240: f(x)= 107.8923935347018
# differential_evolution step 241: f(x)= 107.8923935347018
# differential_evolution step 242: f(x)= 107.8923935347018
# differential_evolution step 243: f(x)= 107.8923935347018
# differential_evolution step 244: f(x)= 107.8923935347018
# differential_evolution step 245: f(x)= 107.8923935347018
# differential_evolution step 246: f(x)= 107.8923935347018
# differential_evolution step 247: f(x)= 107.8923935347018
# differential_evolution step 248: f(x)= 107.8923935347018
# differential_evolution step 249: f(x)= 107.8923935347018
# differential_evolution step 250: f(x)= 107.8923935347018
# differential_evolution step 251: f(x)= 107.8923935347018
# differential_evolution step 252: f(x)= 107.8923935347018
# differential_evolution step 253: f(x)= 107.8923935347018
# differential_evolution step 254: f(x)= 107.8923935347018
# differential_evolution step 255: f(x)= 107.8923935347018
# differential_evolution step 256: f(x)= 107.8923935347018
# differential_evolution step 257: f(x)= 107.8923935347018
# differential_evolution step 258: f(x)= 107.8923935347018
# differential_evolution step 259: f(x)= 107.8923935347018
# differential_evolution step 260: f(x)= 107.88527949439954
# differential_evolution step 261: f(x)= 107.88527949439954
# differential_evolution step 262: f(x)= 107.88527949439954
# differential_evolution step 263: f(x)= 107.88527949439954
# differential_evolution step 264: f(x)= 107.88527949439954
# differential_evolution step 265: f(x)= 107.88527949439954
# differential_evolution step 266: f(x)= 107.88527949439954
# differential_evolution step 267: f(x)= 107.88527949439954
# differential_evolution step 268: f(x)= 107.88527949439954
# differential_evolution step 269: f(x)= 107.88527949439954
# differential_evolution step 270: f(x)= 107.88527949439954
# differential_evolution step 271: f(x)= 107.88527949439954
# differential_evolution step 272: f(x)= 107.88527949439954
# differential_evolution step 273: f(x)= 107.88527949439954
# differential_evolution step 274: f(x)= 107.83495332082089
# differential_evolution step 275: f(x)= 107.83495332082089
# differential_evolution step 276: f(x)= 107.83495332082089
# differential_evolution step 277: f(x)= 107.83495332082089
# differential_evolution step 278: f(x)= 107.83495332082089
# differential_evolution step 279: f(x)= 107.83495332082089
# differential_evolution step 280: f(x)= 107.83495332082089
# differential_evolution step 281: f(x)= 107.83495332082089
# differential_evolution step 282: f(x)= 107.83495332082089
# differential_evolution step 283: f(x)= 107.83495332082089
# differential_evolution step 284: f(x)= 107.83495332082089
# differential_evolution step 285: f(x)= 107.83495332082089
# differential_evolution step 286: f(x)= 107.83495332082089
# differential_evolution step 287: f(x)= 107.83495332082089
# differential_evolution step 288: f(x)= 107.83495332082089
# differential_evolution step 289: f(x)= 107.83495332082089
# differential_evolution step 290: f(x)= 107.83495332082089
# differential_evolution step 291: f(x)= 107.83495332082089
# differential_evolution step 292: f(x)= 107.83495332082089
# differential_evolution step 293: f(x)= 107.83495332082089
# differential_evolution step 294: f(x)= 107.83495332082089
# differential_evolution step 295: f(x)= 107.83495332082089
# differential_evolution step 296: f(x)= 107.83495332082089
# differential_evolution step 297: f(x)= 107.83495332082089
# differential_evolution step 298: f(x)= 107.83495332082089
# differential_evolution step 299: f(x)= 107.83009655900285
# differential_evolution step 300: f(x)= 107.83009655900285
# differential_evolution step 301: f(x)= 107.79662645203942
# differential_evolution step 302: f(x)= 107.78726072225633
# differential_evolution step 303: f(x)= 107.78726072225633
# differential_evolution step 304: f(x)= 107.76705780771533
# differential_evolution step 305: f(x)= 107.76705780771533
# differential_evolution step 306: f(x)= 107.68204358744003
# differential_evolution step 307: f(x)= 107.68204358744003
# differential_evolution step 308: f(x)= 107.65673247451743
# differential_evolution step 309: f(x)= 107.65673247451743
# differential_evolution step 310: f(x)= 107.65673247451743
# differential_evolution step 311: f(x)= 107.65673247451743
# differential_evolution step 312: f(x)= 107.65673247451743
# differential_evolution step 313: f(x)= 107.65673247451743
# differential_evolution step 314: f(x)= 107.65673247451743
# differential_evolution step 315: f(x)= 107.62987804146408
# differential_evolution step 316: f(x)= 107.62987804146408
# differential_evolution step 317: f(x)= 107.62628492946196
# differential_evolution step 318: f(x)= 107.62628492946196
# differential_evolution step 319: f(x)= 107.62628492946196
# differential_evolution step 320: f(x)= 107.62628492946196
# differential_evolution step 321: f(x)= 107.62628492946196
# differential_evolution step 322: f(x)= 107.62104906383365
# differential_evolution step 323: f(x)= 107.58562555116646
# differential_evolution step 324: f(x)= 107.53583334370245
# differential_evolution step 325: f(x)= 107.50770945837498
# differential_evolution step 326: f(x)= 107.50770945837498
# differential_evolution step 327: f(x)= 107.50770945837498
# differential_evolution step 328: f(x)= 107.50770945837498
# differential_evolution step 329: f(x)= 107.50770945837498
# differential_evolution step 330: f(x)= 107.50770945837498
# differential_evolution step 331: f(x)= 107.48015274913588
# differential_evolution step 332: f(x)= 107.41122667589046
# differential_evolution step 333: f(x)= 107.41122667589046
# differential_evolution step 334: f(x)= 107.41122667589046
# differential_evolution step 335: f(x)= 107.41122667589046
# differential_evolution step 336: f(x)= 107.29981966259926
# differential_evolution step 337: f(x)= 107.27162152130583
# differential_evolution step 338: f(x)= 107.27162152130583
# differential_evolution step 339: f(x)= 107.27162152130583
# differential_evolution step 340: f(x)= 107.27162152130583
# differential_evolution step 341: f(x)= 107.21932085378853
# differential_evolution step 342: f(x)= 107.21932085378853
# differential_evolution step 343: f(x)= 107.21932085378853
# differential_evolution step 344: f(x)= 107.21932085378853
# differential_evolution step 345: f(x)= 107.21932085378853
# differential_evolution step 346: f(x)= 107.21932085378853
# differential_evolution step 347: f(x)= 107.20597898195274
# differential_evolution step 348: f(x)= 107.20597898195274
# differential_evolution step 349: f(x)= 107.20597898195274
# differential_evolution step 350: f(x)= 107.20597898195274
# differential_evolution step 351: f(x)= 107.18572569518003
# differential_evolution step 352: f(x)= 107.15653874980013
# differential_evolution step 353: f(x)= 107.15653874980013
# differential_evolution step 354: f(x)= 106.9722522453042
# differential_evolution step 355: f(x)= 106.9722522453042
# differential_evolution step 356: f(x)= 106.9722522453042
# differential_evolution step 357: f(x)= 106.9722522453042
# differential_evolution step 358: f(x)= 106.9722522453042
# differential_evolution step 359: f(x)= 106.86468264588659
# differential_evolution step 360: f(x)= 106.67748417223638
# differential_evolution step 361: f(x)= 106.67748417223638
# differential_evolution step 362: f(x)= 106.61469674330074
# differential_evolution step 363: f(x)= 106.57141344517053
# differential_evolution step 364: f(x)= 106.34235517235123
# differential_evolution step 365: f(x)= 106.34235517235123
# differential_evolution step 366: f(x)= 106.34235517235123
# differential_evolution step 367: f(x)= 106.34235517235123
# differential_evolution step 368: f(x)= 106.34235517235123
# differential_evolution step 369: f(x)= 106.34235517235123
# differential_evolution step 370: f(x)= 106.34235517235123
# differential_evolution step 371: f(x)= 106.34235517235123
# differential_evolution step 372: f(x)= 106.34235517235123
# differential_evolution step 373: f(x)= 106.34235517235123
# differential_evolution step 374: f(x)= 106.34235517235123
# differential_evolution step 375: f(x)= 106.19926262124838
# differential_evolution step 376: f(x)= 106.19926262124838
# differential_evolution step 377: f(x)= 106.19926262124838
# differential_evolution step 378: f(x)= 106.11228962469518
# differential_evolution step 379: f(x)= 106.11228962469518
# differential_evolution step 380: f(x)= 106.11228962469518
# differential_evolution step 381: f(x)= 106.11228962469518
# differential_evolution step 382: f(x)= 106.11228962469518
# differential_evolution step 383: f(x)= 106.11228962469518
# differential_evolution step 384: f(x)= 106.11228962469518
# differential_evolution step 385: f(x)= 106.11228962469518
# differential_evolution step 386: f(x)= 106.11228962469518
# differential_evolution step 387: f(x)= 106.11228962469518
# differential_evolution step 388: f(x)= 105.56517209940758
# differential_evolution step 389: f(x)= 105.56517209940758
# differential_evolution step 390: f(x)= 105.41279634309417
# differential_evolution step 391: f(x)= 105.41279634309417
# differential_evolution step 392: f(x)= 105.26454888979931
# differential_evolution step 393: f(x)= 105.26454888979931
# differential_evolution step 394: f(x)= 105.26454888979931
# differential_evolution step 395: f(x)= 105.26454888979931
# differential_evolution step 396: f(x)= 105.26454888979931
# differential_evolution step 397: f(x)= 105.01437680889065
# differential_evolution step 398: f(x)= 105.01437680889065
# differential_evolution step 399: f(x)= 105.01437680889065
# differential_evolution step 400: f(x)= 105.01437680889065
# differential_evolution step 401: f(x)= 105.01437680889065
# differential_evolution step 402: f(x)= 105.01437680889065
# differential_evolution step 403: f(x)= 105.01437680889065
# differential_evolution step 404: f(x)= 105.01437680889065
# differential_evolution step 405: f(x)= 105.01437680889065
# differential_evolution step 406: f(x)= 105.01437680889065
# differential_evolution step 407: f(x)= 104.96691882302628
# differential_evolution step 408: f(x)= 104.96691882302628
# differential_evolution step 409: f(x)= 104.62003271728464
# differential_evolution step 410: f(x)= 104.62003271728464
# differential_evolution step 411: f(x)= 104.62003271728464
# differential_evolution step 412: f(x)= 104.62003271728464
# differential_evolution step 413: f(x)= 104.62003271728464
# differential_evolution step 414: f(x)= 104.62003271728464
# differential_evolution step 415: f(x)= 104.62003271728464
# differential_evolution step 416: f(x)= 104.62003271728464
# differential_evolution step 417: f(x)= 104.62003271728464
# differential_evolution step 418: f(x)= 104.62003271728464
# differential_evolution step 419: f(x)= 104.62003271728464
# differential_evolution step 420: f(x)= 104.62003271728464
# differential_evolution step 421: f(x)= 104.62003271728464
# differential_evolution step 422: f(x)= 104.62003271728464
# differential_evolution step 423: f(x)= 104.45681964595006
# differential_evolution step 424: f(x)= 104.45681964595006
# differential_evolution step 425: f(x)= 104.15211279504929
# differential_evolution step 426: f(x)= 104.15211279504929
# differential_evolution step 427: f(x)= 104.15211279504929
# differential_evolution step 428: f(x)= 104.15211279504929
# differential_evolution step 429: f(x)= 104.15211279504929
# differential_evolution step 430: f(x)= 104.15211279504929
# differential_evolution step 431: f(x)= 103.79494546182626
# differential_evolution step 432: f(x)= 103.79494546182626
# differential_evolution step 433: f(x)= 103.24291443640591
# differential_evolution step 434: f(x)= 103.24291443640591
# differential_evolution step 435: f(x)= 103.24291443640591
# differential_evolution step 436: f(x)= 103.24291443640591
# differential_evolution step 437: f(x)= 103.24291443640591
# differential_evolution step 438: f(x)= 103.24291443640591
# differential_evolution step 439: f(x)= 103.24291443640591
# differential_evolution step 440: f(x)= 103.24291443640591
# differential_evolution step 441: f(x)= 103.24291443640591
# differential_evolution step 442: f(x)= 103.24291443640591
# differential_evolution step 443: f(x)= 102.76215641694736
# differential_evolution step 444: f(x)= 102.76215641694736
# differential_evolution step 445: f(x)= 102.76215641694736
# differential_evolution step 446: f(x)= 102.34239335673065
# differential_evolution step 447: f(x)= 102.34239335673065
# differential_evolution step 448: f(x)= 102.34239335673065
# differential_evolution step 449: f(x)= 102.34239335673065
# differential_evolution step 450: f(x)= 102.34239335673065
# differential_evolution step 451: f(x)= 102.34239335673065
# differential_evolution step 452: f(x)= 102.34239335673065
# differential_evolution step 453: f(x)= 102.34239335673065
# differential_evolution step 454: f(x)= 101.8432502674614
# differential_evolution step 455: f(x)= 101.8432502674614
# differential_evolution step 456: f(x)= 101.8432502674614
# differential_evolution step 457: f(x)= 101.8432502674614
# differential_evolution step 458: f(x)= 101.30812799715484
# differential_evolution step 459: f(x)= 101.02472081345817
# differential_evolution step 460: f(x)= 100.6775436496151
# differential_evolution step 461: f(x)= 100.6775436496151
# differential_evolution step 462: f(x)= 100.60941157479805
# differential_evolution step 463: f(x)= 100.60941157479805
# differential_evolution step 464: f(x)= 100.58526355919449
# differential_evolution step 465: f(x)= 100.58526355919449
# differential_evolution step 466: f(x)= 100.5716439791744
# differential_evolution step 467: f(x)= 100.5716439791744
# differential_evolution step 468: f(x)= 100.5716439791744
# differential_evolution step 469: f(x)= 100.5716439791744
# differential_evolution step 470: f(x)= 100.5716439791744
# differential_evolution step 471: f(x)= 100.5716439791744
# differential_evolution step 472: f(x)= 100.08540226313279
# differential_evolution step 473: f(x)= 100.08540226313279
# differential_evolution step 474: f(x)= 100.08540226313279
# differential_evolution step 475: f(x)= 100.08540226313279
# differential_evolution step 476: f(x)= 100.08540226313279
# differential_evolution step 477: f(x)= 100.08540226313279
# differential_evolution step 478: f(x)= 99.98877515171975
# differential_evolution step 479: f(x)= 99.98877515171975
# differential_evolution step 480: f(x)= 99.98877515171975
# differential_evolution step 481: f(x)= 99.98877515171975
# differential_evolution step 482: f(x)= 99.98877515171975
# differential_evolution step 483: f(x)= 99.4169386143882
# differential_evolution step 484: f(x)= 98.86007140531584
# differential_evolution step 485: f(x)= 98.75658061197889
# differential_evolution step 486: f(x)= 98.75442166144668
# differential_evolution step 487: f(x)= 97.8039368207476
# differential_evolution step 488: f(x)= 97.8039368207476
# differential_evolution step 489: f(x)= 97.8039368207476
# differential_evolution step 490: f(x)= 97.8039368207476
# differential_evolution step 491: f(x)= 97.72104685541893
# differential_evolution step 492: f(x)= 97.67860289926598
# differential_evolution step 493: f(x)= 97.67860289926598
# differential_evolution step 494: f(x)= 97.19496031651089
# differential_evolution step 495: f(x)= 96.8347545678549
# differential_evolution step 496: f(x)= 96.8347545678549
# differential_evolution step 497: f(x)= 96.30081270323059
# differential_evolution step 498: f(x)= 96.30081270323059
# differential_evolution step 499: f(x)= 96.30081270323059
# differential_evolution step 500: f(x)= 96.30081270323059
# differential_evolution step 501: f(x)= 96.30081270323059
# differential_evolution step 502: f(x)= 96.30081270323059
# differential_evolution step 503: f(x)= 96.30081270323059
# differential_evolution step 504: f(x)= 96.30081270323059
# differential_evolution step 505: f(x)= 95.64182277814083
# differential_evolution step 506: f(x)= 95.64182277814083
# differential_evolution step 507: f(x)= 95.64182277814083
# differential_evolution step 508: f(x)= 95.64182277814083
# differential_evolution step 509: f(x)= 95.64182277814083
# differential_evolution step 510: f(x)= 95.64182277814083
# differential_evolution step 511: f(x)= 95.64182277814083
# differential_evolution step 512: f(x)= 95.3623793142862
# differential_evolution step 513: f(x)= 95.3623793142862
# differential_evolution step 514: f(x)= 95.3623793142862
# differential_evolution step 515: f(x)= 95.25842895744057
# differential_evolution step 516: f(x)= 95.25842895744057
# differential_evolution step 517: f(x)= 95.25842895744057
# differential_evolution step 518: f(x)= 95.25842895744057
# differential_evolution step 519: f(x)= 93.35480414742449
# differential_evolution step 520: f(x)= 93.35480414742449
# differential_evolution step 521: f(x)= 93.35480414742449
# differential_evolution step 522: f(x)= 93.35480414742449
# differential_evolution step 523: f(x)= 92.84366285045186
# differential_evolution step 524: f(x)= 92.84366285045186
# differential_evolution step 525: f(x)= 92.84366285045186
# differential_evolution step 526: f(x)= 92.40555955501858
# differential_evolution step 527: f(x)= 92.40555955501858
# differential_evolution step 528: f(x)= 92.40555955501858
# differential_evolution step 529: f(x)= 92.40555955501858
# differential_evolution step 530: f(x)= 92.40555955501858
# differential_evolution step 531: f(x)= 92.40555955501858
# differential_evolution step 532: f(x)= 92.40555955501858
# differential_evolution step 533: f(x)= 92.40555955501858
# differential_evolution step 534: f(x)= 92.15747015612254
# differential_evolution step 535: f(x)= 92.02616333593299
# differential_evolution step 536: f(x)= 92.02616333593299
# differential_evolution step 537: f(x)= 92.02616333593299
# differential_evolution step 538: f(x)= 91.99428384973655
# differential_evolution step 539: f(x)= 91.99428384973655
# differential_evolution step 540: f(x)= 91.63739219659746
# differential_evolution step 541: f(x)= 91.63739219659746
# differential_evolution step 542: f(x)= 91.63739219659746
# differential_evolution step 543: f(x)= 91.63739219659746
# differential_evolution step 544: f(x)= 91.51018271517579
# differential_evolution step 545: f(x)= 90.93164140192556
# differential_evolution step 546: f(x)= 90.93164140192556
# differential_evolution step 547: f(x)= 90.93164140192556
# differential_evolution step 548: f(x)= 90.93164140192556
# differential_evolution step 549: f(x)= 90.93164140192556
# differential_evolution step 550: f(x)= 90.93164140192556
# differential_evolution step 551: f(x)= 90.93164140192556
# differential_evolution step 552: f(x)= 90.16838513702622
# differential_evolution step 553: f(x)= 90.16838513702622
# differential_evolution step 554: f(x)= 90.16838513702622
# differential_evolution step 555: f(x)= 90.16838513702622
# differential_evolution step 556: f(x)= 90.16838513702622
# differential_evolution step 557: f(x)= 90.16838513702622
# differential_evolution step 558: f(x)= 90.16838513702622
# differential_evolution step 559: f(x)= 90.16838513702622
# differential_evolution step 560: f(x)= 90.16838513702622
# differential_evolution step 561: f(x)= 90.15059673417049
# differential_evolution step 562: f(x)= 90.15059673417049
# differential_evolution step 563: f(x)= 89.85879096604637
# differential_evolution step 564: f(x)= 89.68646270178078
# differential_evolution step 565: f(x)= 89.68646270178078
# differential_evolution step 566: f(x)= 89.68646270178078
# differential_evolution step 567: f(x)= 89.68646270178078
# differential_evolution step 568: f(x)= 89.68646270178078
# differential_evolution step 569: f(x)= 89.68646270178078
# differential_evolution step 570: f(x)= 89.68646270178078
# differential_evolution step 571: f(x)= 89.30097959039333
# differential_evolution step 572: f(x)= 89.30097959039333
# differential_evolution step 573: f(x)= 89.30097959039333
# differential_evolution step 574: f(x)= 89.30097959039333
# differential_evolution step 575: f(x)= 89.30097959039333
# differential_evolution step 576: f(x)= 89.30097959039333
# differential_evolution step 577: f(x)= 89.30097959039333
# differential_evolution step 578: f(x)= 89.30097959039333
# differential_evolution step 579: f(x)= 88.83924815568032
# differential_evolution step 580: f(x)= 88.59485684212144
# differential_evolution step 581: f(x)= 88.59485684212144
# differential_evolution step 582: f(x)= 88.59485684212144
# differential_evolution step 583: f(x)= 88.59485684212144
# differential_evolution step 584: f(x)= 88.59427829538824
# differential_evolution step 585: f(x)= 88.59427829538824
# differential_evolution step 586: f(x)= 88.59427829538824
# differential_evolution step 587: f(x)= 88.59427829538824
# differential_evolution step 588: f(x)= 87.80423801271995
# differential_evolution step 589: f(x)= 87.80423801271995
# differential_evolution step 590: f(x)= 87.80423801271995
# differential_evolution step 591: f(x)= 87.80423801271995
# differential_evolution step 592: f(x)= 87.80423801271995
# differential_evolution step 593: f(x)= 87.80423801271995
# differential_evolution step 594: f(x)= 87.80423801271995
# differential_evolution step 595: f(x)= 87.80423801271995
# differential_evolution step 596: f(x)= 87.80423801271995
# differential_evolution step 597: f(x)= 87.80423801271995
# differential_evolution step 598: f(x)= 87.80423801271995
# differential_evolution step 599: f(x)= 87.80423801271995
# differential_evolution step 600: f(x)= 87.80423801271995
# differential_evolution step 601: f(x)= 87.80423801271995
# differential_evolution step 602: f(x)= 87.80423801271995
# differential_evolution step 603: f(x)= 87.80423801271995
# differential_evolution step 604: f(x)= 87.80423801271995
# differential_evolution step 605: f(x)= 87.80423801271995
# differential_evolution step 606: f(x)= 87.80423801271995
# differential_evolution step 607: f(x)= 87.80423801271995
# differential_evolution step 608: f(x)= 87.80423801271995
# differential_evolution step 609: f(x)= 87.80423801271995
# differential_evolution step 610: f(x)= 87.80423801271995
# differential_evolution step 611: f(x)= 87.80423801271995
# differential_evolution step 612: f(x)= 87.80423801271995
# differential_evolution step 613: f(x)= 87.6502271177483
# differential_evolution step 614: f(x)= 87.6502271177483
# differential_evolution step 615: f(x)= 87.6502271177483
# differential_evolution step 616: f(x)= 87.6502271177483
# differential_evolution step 617: f(x)= 87.6502271177483
# differential_evolution step 618: f(x)= 87.6502271177483
# differential_evolution step 619: f(x)= 87.6502271177483
# differential_evolution step 620: f(x)= 87.6502271177483
# differential_evolution step 621: f(x)= 87.6502271177483
# differential_evolution step 622: f(x)= 87.6502271177483
# differential_evolution step 623: f(x)= 87.6502271177483
# differential_evolution step 624: f(x)= 87.6502271177483
# differential_evolution step 625: f(x)= 87.63403566375555
# differential_evolution step 626: f(x)= 87.54704436211243
# differential_evolution step 627: f(x)= 87.54704436211243
# differential_evolution step 628: f(x)= 87.54704436211243
# differential_evolution step 629: f(x)= 87.46794109836922
# differential_evolution step 630: f(x)= 87.46794109836922
# differential_evolution step 631: f(x)= 87.46794109836922
# differential_evolution step 632: f(x)= 87.46794109836922
# differential_evolution step 633: f(x)= 87.37029727138201
# differential_evolution step 634: f(x)= 87.37029727138201
# differential_evolution step 635: f(x)= 87.26715283993167
# differential_evolution step 636: f(x)= 87.26715283993167
# differential_evolution step 637: f(x)= 87.26715283993167
# differential_evolution step 638: f(x)= 87.26715283993167
# differential_evolution step 639: f(x)= 87.26715283993167
# differential_evolution step 640: f(x)= 87.26715283993167
# differential_evolution step 641: f(x)= 87.26715283993167
# differential_evolution step 642: f(x)= 87.26715283993167
# differential_evolution step 643: f(x)= 87.26715283993167
# differential_evolution step 644: f(x)= 87.26715283993167
# differential_evolution step 645: f(x)= 87.26715283993167
# differential_evolution step 646: f(x)= 87.26715283993167
# differential_evolution step 647: f(x)= 87.25291881088826
# differential_evolution step 648: f(x)= 87.25291881088826
# differential_evolution step 649: f(x)= 87.17055186689127
# differential_evolution step 650: f(x)= 87.17055186689127
# differential_evolution step 651: f(x)= 87.17055186689127
# differential_evolution step 652: f(x)= 87.17055186689127
# differential_evolution step 653: f(x)= 87.17055186689127
# differential_evolution step 654: f(x)= 87.17055186689127
# differential_evolution step 655: f(x)= 87.17055186689127
# differential_evolution step 656: f(x)= 87.15046126967002
# differential_evolution step 657: f(x)= 87.15046126967002
# differential_evolution step 658: f(x)= 87.15046126967002
# differential_evolution step 659: f(x)= 87.15046126967002
# differential_evolution step 660: f(x)= 87.15046126967002
# differential_evolution step 661: f(x)= 87.15046126967002
# differential_evolution step 662: f(x)= 87.15046126967002
# differential_evolution step 663: f(x)= 87.15046126967002
# differential_evolution step 664: f(x)= 87.15046126967002
# differential_evolution step 665: f(x)= 87.15046126967002
# differential_evolution step 666: f(x)= 87.15046126967002
# differential_evolution step 667: f(x)= 87.15046126967002
# differential_evolution step 668: f(x)= 87.15046126967002
# differential_evolution step 669: f(x)= 87.15046126967002
# differential_evolution step 670: f(x)= 87.15046126967002
# differential_evolution step 671: f(x)= 87.15046126967002
# differential_evolution step 672: f(x)= 87.15046126967002
# differential_evolution step 673: f(x)= 87.15046126967002
# differential_evolution step 674: f(x)= 87.15046126967002
# differential_evolution step 675: f(x)= 87.15046126967002
# differential_evolution step 676: f(x)= 87.15046126967002
# differential_evolution step 677: f(x)= 87.15046126967002
# differential_evolution step 678: f(x)= 87.15046126967002
# differential_evolution step 679: f(x)= 87.15046126967002
# differential_evolution step 680: f(x)= 87.15046126967002
# differential_evolution step 681: f(x)= 87.15046126967002
# differential_evolution step 682: f(x)= 87.15046126967002
# differential_evolution step 683: f(x)= 87.12807143720528
# differential_evolution step 684: f(x)= 87.12807143720528
# differential_evolution step 685: f(x)= 87.12807143720528
# differential_evolution step 686: f(x)= 87.12807143720528
# differential_evolution step 687: f(x)= 87.12807143720528
# differential_evolution step 688: f(x)= 87.12568677500562
# differential_evolution step 689: f(x)= 87.12568677500562
# differential_evolution step 690: f(x)= 87.11334324835751
# differential_evolution step 691: f(x)= 87.11334324835751
# differential_evolution step 692: f(x)= 87.11334324835751
# differential_evolution step 693: f(x)= 87.11334324835751
# differential_evolution step 694: f(x)= 87.11334324835751
# differential_evolution step 695: f(x)= 87.11334324835751
# differential_evolution step 696: f(x)= 87.11334324835751
# differential_evolution step 697: f(x)= 87.11149689516563
# differential_evolution step 698: f(x)= 87.11149689516563
# differential_evolution step 699: f(x)= 87.11149689516563
# differential_evolution step 700: f(x)= 87.11149689516563
# differential_evolution step 701: f(x)= 87.11149689516563
# differential_evolution step 702: f(x)= 87.11149689516563
# differential_evolution step 703: f(x)= 87.11149689516563
# differential_evolution step 704: f(x)= 87.11149689516563
# differential_evolution step 705: f(x)= 87.11149689516563
# differential_evolution step 706: f(x)= 87.11149689516563
# differential_evolution step 707: f(x)= 87.11149689516563
# differential_evolution step 708: f(x)= 87.11149689516563
# differential_evolution step 709: f(x)= 87.11149689516563
# differential_evolution step 710: f(x)= 87.11149689516563
# differential_evolution step 711: f(x)= 87.11011621386676
# differential_evolution step 712: f(x)= 87.11011621386676
# differential_evolution step 713: f(x)= 87.11011621386676
# differential_evolution step 714: f(x)= 87.11011621386676
# differential_evolution step 715: f(x)= 87.0966109911901
# differential_evolution step 716: f(x)= 87.0966109911901
# differential_evolution step 717: f(x)= 87.07924031183997
# differential_evolution step 718: f(x)= 87.07924031183997
# differential_evolution step 719: f(x)= 87.07924031183997
# differential_evolution step 720: f(x)= 87.07924031183997
# differential_evolution step 721: f(x)= 87.07924031183997
# differential_evolution step 722: f(x)= 87.0778072246433
# differential_evolution step 723: f(x)= 87.0778072246433
# differential_evolution step 724: f(x)= 87.0778072246433
# differential_evolution step 725: f(x)= 87.0778072246433
# differential_evolution step 726: f(x)= 87.07474366512287
# differential_evolution step 727: f(x)= 87.07474366512287
# differential_evolution step 728: f(x)= 87.07474366512287
# differential_evolution step 729: f(x)= 87.07474366512287
# differential_evolution step 730: f(x)= 87.07474366512287
# differential_evolution step 731: f(x)= 87.07474366512287
# differential_evolution step 732: f(x)= 87.07474366512287
# differential_evolution step 733: f(x)= 87.07474366512287
# differential_evolution step 734: f(x)= 87.07284023568057
# differential_evolution step 735: f(x)= 87.07284023568057
# differential_evolution step 736: f(x)= 87.07284023568057
# differential_evolution step 737: f(x)= 87.07284023568057
# differential_evolution step 738: f(x)= 87.07284023568057
# differential_evolution step 739: f(x)= 87.07284023568057
# differential_evolution step 740: f(x)= 87.07284023568057
# differential_evolution step 741: f(x)= 87.07284023568057
# differential_evolution step 742: f(x)= 87.07284023568057
# differential_evolution step 743: f(x)= 87.07284023568057
# differential_evolution step 744: f(x)= 87.07284023568057
# differential_evolution step 745: f(x)= 87.07284023568057
# differential_evolution step 746: f(x)= 87.07284023568057
# differential_evolution step 747: f(x)= 87.07284023568057
# differential_evolution step 748: f(x)= 87.07284023568057
# differential_evolution step 749: f(x)= 87.07284023568057
# differential_evolution step 750: f(x)= 87.07284023568057
# differential_evolution step 751: f(x)= 87.07284023568057
# differential_evolution step 752: f(x)= 87.07284023568057
# differential_evolution step 753: f(x)= 87.07284023568057
# differential_evolution step 754: f(x)= 87.06552846851439
# differential_evolution step 755: f(x)= 87.06552846851439
# differential_evolution step 756: f(x)= 87.06552846851439
# differential_evolution step 757: f(x)= 87.06552846851439
# differential_evolution step 758: f(x)= 87.06552846851439
# differential_evolution step 759: f(x)= 87.06552846851439
# differential_evolution step 760: f(x)= 87.06552846851439
# differential_evolution step 761: f(x)= 87.06552846851439
# differential_evolution step 762: f(x)= 87.06552846851439
# differential_evolution step 763: f(x)= 87.06245523753896
# differential_evolution step 764: f(x)= 87.06245523753896
# differential_evolution step 765: f(x)= 87.06245523753896
# differential_evolution step 766: f(x)= 87.06245523753896
# differential_evolution step 767: f(x)= 87.06245523753896
# differential_evolution step 768: f(x)= 87.06245523753896
# differential_evolution step 769: f(x)= 87.06245523753896
# differential_evolution step 770: f(x)= 87.06245523753896
# differential_evolution step 771: f(x)= 87.04550883834216
# differential_evolution step 772: f(x)= 87.04550883834216
# differential_evolution step 773: f(x)= 87.04550883834216
# differential_evolution step 774: f(x)= 87.04550883834216
# differential_evolution step 775: f(x)= 87.04550237023858
# differential_evolution step 776: f(x)= 87.04550237023858
# differential_evolution step 777: f(x)= 87.04550237023858
# differential_evolution step 778: f(x)= 87.04550237023858
# differential_evolution step 779: f(x)= 87.04550237023858
# differential_evolution step 780: f(x)= 87.04550237023858
# differential_evolution step 781: f(x)= 87.04550237023858
# differential_evolution step 782: f(x)= 87.04550237023858
# differential_evolution step 783: f(x)= 87.04550237023858
# differential_evolution step 784: f(x)= 87.04550237023858
# differential_evolution step 785: f(x)= 87.04550237023858
# differential_evolution step 786: f(x)= 87.04550237023858
# differential_evolution step 787: f(x)= 87.04550237023858
# differential_evolution step 788: f(x)= 87.04550237023858
# differential_evolution step 789: f(x)= 87.04550237023858
# differential_evolution step 790: f(x)= 87.04040155248369
# differential_evolution step 791: f(x)= 87.04040155248369
# differential_evolution step 792: f(x)= 87.04040155248369
# differential_evolution step 793: f(x)= 87.04040155248369
# differential_evolution step 794: f(x)= 87.04040155248369
# differential_evolution step 795: f(x)= 87.04040155248369
# differential_evolution step 796: f(x)= 87.04040155248369
# differential_evolution step 797: f(x)= 87.04040155248369
# differential_evolution step 798: f(x)= 87.04040155248369
# differential_evolution step 799: f(x)= 87.04040155248369
# differential_evolution step 800: f(x)= 87.04040155248369
# differential_evolution step 801: f(x)= 87.04040155248369
# differential_evolution step 802: f(x)= 87.04040155248369
# differential_evolution step 803: f(x)= 87.04007464775106
# differential_evolution step 804: f(x)= 87.04007464775106
# differential_evolution step 805: f(x)= 87.04007464775106
# differential_evolution step 806: f(x)= 87.04007464775106
# differential_evolution step 807: f(x)= 87.03980110069529
# differential_evolution step 808: f(x)= 87.03980110069529
# differential_evolution step 809: f(x)= 87.03980110069529
# differential_evolution step 810: f(x)= 87.03980110069529
# differential_evolution step 811: f(x)= 87.03980110069529
# differential_evolution step 812: f(x)= 87.03980110069529
# differential_evolution step 813: f(x)= 87.03980110069529
# differential_evolution step 814: f(x)= 87.03980110069529
# differential_evolution step 815: f(x)= 87.03980110069529
# differential_evolution step 816: f(x)= 87.03980110069529
# differential_evolution step 817: f(x)= 87.03980110069529
# differential_evolution step 818: f(x)= 87.03980110069529
# differential_evolution step 819: f(x)= 87.03980110069529
# differential_evolution step 820: f(x)= 87.03980110069529
# differential_evolution step 821: f(x)= 87.03980110069529
# differential_evolution step 822: f(x)= 87.03980110069529
# differential_evolution step 823: f(x)= 87.03980110069529
# differential_evolution step 824: f(x)= 87.03980110069529
# differential_evolution step 825: f(x)= 87.03980110069529
# differential_evolution step 826: f(x)= 87.03980110069529
# differential_evolution step 827: f(x)= 87.03980110069529
# differential_evolution step 828: f(x)= 87.03980110069529
# differential_evolution step 829: f(x)= 87.03980110069529
# differential_evolution step 830: f(x)= 87.03980110069529
# differential_evolution step 831: f(x)= 87.03980110069529
# differential_evolution step 832: f(x)= 87.03904351039154
# differential_evolution step 833: f(x)= 87.03676190398757
# differential_evolution step 834: f(x)= 87.03676190398757
# differential_evolution step 835: f(x)= 87.03676190398757
# differential_evolution step 836: f(x)= 87.03613433117776
# differential_evolution step 837: f(x)= 87.03613433117776
# differential_evolution step 838: f(x)= 87.03613433117776
# differential_evolution step 839: f(x)= 87.03613433117776
# differential_evolution step 840: f(x)= 87.03613433117776
# differential_evolution step 841: f(x)= 87.03613433117776
# differential_evolution step 842: f(x)= 87.03613433117776
# differential_evolution step 843: f(x)= 87.03613433117776
# differential_evolution step 844: f(x)= 87.03583512852919
# differential_evolution step 845: f(x)= 87.03583512852919
# differential_evolution step 846: f(x)= 87.03583512852919
# differential_evolution step 847: f(x)= 87.03583512852919
# differential_evolution step 848: f(x)= 87.03583512852919
# differential_evolution step 849: f(x)= 87.03323844393722
# differential_evolution step 850: f(x)= 87.03323844393722
# differential_evolution step 851: f(x)= 87.03323844393722
# differential_evolution step 852: f(x)= 87.03323844393722
# differential_evolution step 853: f(x)= 87.03323844393722
# differential_evolution step 854: f(x)= 87.03323844393722
# differential_evolution step 855: f(x)= 87.03323844393722
# differential_evolution step 856: f(x)= 87.03323844393722
# differential_evolution step 857: f(x)= 87.03323844393722
# differential_evolution step 858: f(x)= 87.03323844393722
# differential_evolution step 859: f(x)= 87.03323844393722
# differential_evolution step 860: f(x)= 87.03323844393722
# differential_evolution step 861: f(x)= 87.03323844393722
# differential_evolution step 862: f(x)= 87.03323844393722
# differential_evolution step 863: f(x)= 87.03323844393722
# differential_evolution step 864: f(x)= 87.03323844393722
# differential_evolution step 865: f(x)= 87.03323844393722
# differential_evolution step 866: f(x)= 87.03323844393722
# differential_evolution step 867: f(x)= 87.03290415732195
# differential_evolution step 868: f(x)= 87.03290415732195
# differential_evolution step 869: f(x)= 87.03290415732195
# differential_evolution step 870: f(x)= 87.03290415732195
# differential_evolution step 871: f(x)= 87.03290415732195
# differential_evolution step 872: f(x)= 87.03290415732195
# differential_evolution step 873: f(x)= 87.03290415732195
# differential_evolution step 874: f(x)= 87.03290415732195
# differential_evolution step 875: f(x)= 87.03290415732195
# differential_evolution step 876: f(x)= 87.03290415732195
# differential_evolution step 877: f(x)= 87.03290415732195
# differential_evolution step 878: f(x)= 87.03290415732195
# differential_evolution step 879: f(x)= 87.03290415732195
# differential_evolution step 880: f(x)= 87.03290415732195
# differential_evolution step 881: f(x)= 87.03165571184051
# differential_evolution step 882: f(x)= 87.03165571184051
# differential_evolution step 883: f(x)= 87.03165571184051
# differential_evolution step 884: f(x)= 87.03165571184051
# differential_evolution step 885: f(x)= 87.03165571184051
# differential_evolution step 886: f(x)= 87.03165571184051
# differential_evolution step 887: f(x)= 87.03165571184051
# differential_evolution step 888: f(x)= 87.03165571184051
# differential_evolution step 889: f(x)= 87.03165571184051
# differential_evolution step 890: f(x)= 87.03165571184051
# differential_evolution step 891: f(x)= 87.03165571184051
# differential_evolution step 892: f(x)= 87.03165571184051
# differential_evolution step 893: f(x)= 87.03102238476934
# differential_evolution step 894: f(x)= 87.03102238476934
# differential_evolution step 895: f(x)= 87.03102238476934
# differential_evolution step 896: f(x)= 87.03045003355332
# differential_evolution step 897: f(x)= 87.03045003355332
# differential_evolution step 898: f(x)= 87.03045003355332
# differential_evolution step 899: f(x)= 87.03045003355332
# differential_evolution step 900: f(x)= 87.03045003355332
# differential_evolution step 901: f(x)= 87.03045003355332
# differential_evolution step 902: f(x)= 87.03045003355332
# differential_evolution step 903: f(x)= 87.03045003355332
# differential_evolution step 904: f(x)= 87.03045003355332
# differential_evolution step 905: f(x)= 87.03045003355332
# differential_evolution step 906: f(x)= 87.03045003355332
# differential_evolution step 907: f(x)= 87.03045003355332
# differential_evolution step 908: f(x)= 87.03045003355332
# differential_evolution step 909: f(x)= 87.03045003355332
# differential_evolution step 910: f(x)= 87.03045003355332
# differential_evolution step 911: f(x)= 87.03045003355332
# differential_evolution step 912: f(x)= 87.03045003355332
# differential_evolution step 913: f(x)= 87.03045003355332
# differential_evolution step 914: f(x)= 87.03045003355332
# differential_evolution step 915: f(x)= 87.03045003355332
# differential_evolution step 916: f(x)= 87.02974547731249
# differential_evolution step 917: f(x)= 87.02974547731249
# differential_evolution step 918: f(x)= 87.02974547731249
# differential_evolution step 919: f(x)= 87.02974547731249
# differential_evolution step 920: f(x)= 87.02974547731249
# differential_evolution step 921: f(x)= 87.02974547731249
# differential_evolution step 922: f(x)= 87.02974547731249
# differential_evolution step 923: f(x)= 87.02974547731249
# differential_evolution step 924: f(x)= 87.02974547731249
# differential_evolution step 925: f(x)= 87.02974547731249
# differential_evolution step 926: f(x)= 87.02974547731249
# differential_evolution step 927: f(x)= 87.02974547731249
# differential_evolution step 928: f(x)= 87.02974547731249
# differential_evolution step 929: f(x)= 87.02974547731249
# differential_evolution step 930: f(x)= 87.02974547731249
# differential_evolution step 931: f(x)= 87.02974547731249
# differential_evolution step 932: f(x)= 87.02974547731249
# differential_evolution step 933: f(x)= 87.02974547731249
# differential_evolution step 934: f(x)= 87.02974547731249
# differential_evolution step 935: f(x)= 87.02974547731249
# differential_evolution step 936: f(x)= 87.02974547731249
# differential_evolution step 937: f(x)= 87.02974547731249
# differential_evolution step 938: f(x)= 87.02974547731249
# differential_evolution step 939: f(x)= 87.02974547731249
# differential_evolution step 940: f(x)= 87.02969531048709
# differential_evolution step 941: f(x)= 87.02969531048709
# differential_evolution step 942: f(x)= 87.02969531048709
# differential_evolution step 943: f(x)= 87.02969531048709
# differential_evolution step 944: f(x)= 87.02969531048709
# differential_evolution step 945: f(x)= 87.02969531048709
# differential_evolution step 946: f(x)= 87.02969531048709
# differential_evolution step 947: f(x)= 87.02969531048709
# differential_evolution step 948: f(x)= 87.02969531048709
# differential_evolution step 949: f(x)= 87.02969531048709
# differential_evolution step 950: f(x)= 87.02969531048709
# differential_evolution step 951: f(x)= 87.02969531048709
# differential_evolution step 952: f(x)= 87.02969531048709
# differential_evolution step 953: f(x)= 87.0295467670401
# differential_evolution step 954: f(x)= 87.0295467670401
# differential_evolution step 955: f(x)= 87.0295467670401
# differential_evolution step 956: f(x)= 87.0295467670401
# differential_evolution step 957: f(x)= 87.0295467670401
# differential_evolution step 958: f(x)= 87.0295467670401
# differential_evolution step 959: f(x)= 87.0295467670401
# differential_evolution step 960: f(x)= 87.0295467670401
# differential_evolution step 961: f(x)= 87.0295467670401
# differential_evolution step 962: f(x)= 87.0295467670401
# differential_evolution step 963: f(x)= 87.02948289643453
# differential_evolution step 964: f(x)= 87.02948289643453
# differential_evolution step 965: f(x)= 87.02931735440959
# differential_evolution step 966: f(x)= 87.02931735440959
# differential_evolution step 967: f(x)= 87.02931735440959
# differential_evolution step 968: f(x)= 87.02931735440959
# differential_evolution step 969: f(x)= 87.02931735440959
# differential_evolution step 970: f(x)= 87.02931735440959
# differential_evolution step 971: f(x)= 87.02931735440959
# differential_evolution step 972: f(x)= 87.02926834815338
# differential_evolution step 973: f(x)= 87.02921054062958
# differential_evolution step 974: f(x)= 87.02921054062958
# differential_evolution step 975: f(x)= 87.02921054062958
# differential_evolution step 976: f(x)= 87.02921054062958
# differential_evolution step 977: f(x)= 87.02921054062958
# differential_evolution step 978: f(x)= 87.02921054062958
# differential_evolution step 979: f(x)= 87.02921054062958
# differential_evolution step 980: f(x)= 87.02921054062958
# differential_evolution step 981: f(x)= 87.02921054062958
# differential_evolution step 982: f(x)= 87.02921054062958
# differential_evolution step 983: f(x)= 87.02921054062958
# differential_evolution step 984: f(x)= 87.02921054062958
# differential_evolution step 985: f(x)= 87.02921054062958
# differential_evolution step 986: f(x)= 87.02903457444859
# differential_evolution step 987: f(x)= 87.02903457444859
# differential_evolution step 988: f(x)= 87.02903457444859
# differential_evolution step 989: f(x)= 87.02903457444859
# differential_evolution step 990: f(x)= 87.02903457444859
# differential_evolution step 991: f(x)= 87.02903457444859
# differential_evolution step 992: f(x)= 87.02903457444859
# differential_evolution step 993: f(x)= 87.02903457444859
# differential_evolution step 994: f(x)= 87.02903457444859
# differential_evolution step 995: f(x)= 87.02903457444859
# differential_evolution step 996: f(x)= 87.02903457444859
# differential_evolution step 997: f(x)= 87.02903457444859
# differential_evolution step 998: f(x)= 87.02903457444859
# differential_evolution step 999: f(x)= 87.02903457444859
# differential_evolution step 1000: f(x)= 87.02903457444859
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.6928, r_e=17.5544, n=1.3360, x_0=45.0000
# Sérsic 2: I_e=18.0509, r_e=1.8810, n=0.5344, x_0=51.4596
# Sérsic 3: I_e=17.2635, r_e=5.1745, n=0.8092, x_0=60.7123
# Chi quadro minimo: 87.02854386663371
# False

# %%
plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')

# %%
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA)

print("Optimize parameters with curve fit:")

chi2_reduced_HA_1, dof_HA_1, chi2_HA_1 = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.6212, r_e=18.3895, n=1.4945, x_0=46.6091
# Sérsic 2: I_e=25.9875, r_e=1.4570, n=0.2439, x_0=51.6237
# Sérsic 3: I_e=14.4564, r_e=5.5721, n=0.9455, x_0=60.7396
# [ 0.18128523  0.73425985  0.07105764  0.39656987 14.89902705  0.17908407
#   0.53965834  0.14313506  0.75729219  0.13332863  0.05003426  0.13041291]
# 5.768956296967726

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (43, 45),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62), 

     (0, 20),
    (0, 50),
    (0.1, 10),
    (34, 37)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
n_component = 4
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 9675.190743031084
# differential_evolution step 2: f(x)= 9675.190743031084
# differential_evolution step 3: f(x)= 9675.190743031084
# differential_evolution step 4: f(x)= 9675.190743031084
# differential_evolution step 5: f(x)= 9675.190743031084
# differential_evolution step 6: f(x)= 9675.190743031084
# differential_evolution step 7: f(x)= 9675.190743031084
# differential_evolution step 8: f(x)= 9675.190743031084
# differential_evolution step 9: f(x)= 7185.235855110246
# differential_evolution step 10: f(x)= 5935.250472382612
# differential_evolution step 11: f(x)= 5935.250472382612
# differential_evolution step 12: f(x)= 5935.250472382612
# differential_evolution step 13: f(x)= 3534.6134898591836
# differential_evolution step 14: f(x)= 3518.5431285304217
# differential_evolution step 15: f(x)= 3518.5431285304217
# differential_evolution step 16: f(x)= 3518.5431285304217
# differential_evolution step 17: f(x)= 3518.5431285304217
# differential_evolution step 18: f(x)= 3518.5431285304217
# differential_evolution step 19: f(x)= 2201.982603582299
# differential_evolution step 20: f(x)= 2025.6542343927958
# differential_evolution step 21: f(x)= 2025.6542343927958
# differential_evolution step 22: f(x)= 2025.6542343927958
# differential_evolution step 23: f(x)= 2025.6542343927958
# differential_evolution step 24: f(x)= 2025.6542343927958
# differential_evolution step 25: f(x)= 2025.6542343927958
# differential_evolution step 26: f(x)= 2025.6542343927958
# differential_evolution step 27: f(x)= 1502.471080998243
# differential_evolution step 28: f(x)= 1502.471080998243
# differential_evolution step 29: f(x)= 1502.471080998243
# differential_evolution step 30: f(x)= 1502.471080998243
# differential_evolution step 31: f(x)= 1062.7172754917747
# differential_evolution step 32: f(x)= 1047.8675061032466
# differential_evolution step 33: f(x)= 789.1083212954937
# differential_evolution step 34: f(x)= 789.1083212954937
# differential_evolution step 35: f(x)= 789.1083212954937
# differential_evolution step 36: f(x)= 789.1083212954937
# differential_evolution step 37: f(x)= 789.1083212954937
# differential_evolution step 38: f(x)= 789.1083212954937
# differential_evolution step 39: f(x)= 518.6591486341355
# differential_evolution step 40: f(x)= 518.6591486341355
# differential_evolution step 41: f(x)= 518.6591486341355
# differential_evolution step 42: f(x)= 518.6591486341355
# differential_evolution step 43: f(x)= 518.6591486341355
# differential_evolution step 44: f(x)= 518.6591486341355
# differential_evolution step 45: f(x)= 441.21611207209605
# differential_evolution step 46: f(x)= 441.21611207209605
# differential_evolution step 47: f(x)= 441.21611207209605
# differential_evolution step 48: f(x)= 441.21611207209605
# differential_evolution step 49: f(x)= 441.21611207209605
# differential_evolution step 50: f(x)= 441.21611207209605
# differential_evolution step 51: f(x)= 437.2199579275125
# differential_evolution step 52: f(x)= 384.16989777210887
# differential_evolution step 53: f(x)= 384.16989777210887
# differential_evolution step 54: f(x)= 384.16989777210887
# differential_evolution step 55: f(x)= 384.16989777210887
# differential_evolution step 56: f(x)= 290.38113822470854
# differential_evolution step 57: f(x)= 290.38113822470854
# differential_evolution step 58: f(x)= 290.38113822470854
# differential_evolution step 59: f(x)= 290.38113822470854
# differential_evolution step 60: f(x)= 290.38113822470854
# differential_evolution step 61: f(x)= 290.38113822470854
# differential_evolution step 62: f(x)= 290.38113822470854
# differential_evolution step 63: f(x)= 290.38113822470854
# differential_evolution step 64: f(x)= 290.38113822470854
# differential_evolution step 65: f(x)= 290.38113822470854
# differential_evolution step 66: f(x)= 290.38113822470854
# differential_evolution step 67: f(x)= 290.38113822470854
# differential_evolution step 68: f(x)= 290.38113822470854
# differential_evolution step 69: f(x)= 290.38113822470854
# differential_evolution step 70: f(x)= 283.43076352349897
# differential_evolution step 71: f(x)= 283.43076352349897
# differential_evolution step 72: f(x)= 283.43076352349897
# differential_evolution step 73: f(x)= 283.43076352349897
# differential_evolution step 74: f(x)= 283.43076352349897
# differential_evolution step 75: f(x)= 283.43076352349897
# differential_evolution step 76: f(x)= 283.43076352349897
# differential_evolution step 77: f(x)= 200.79104187182466
# differential_evolution step 78: f(x)= 200.79104187182466
# differential_evolution step 79: f(x)= 200.79104187182466
# differential_evolution step 80: f(x)= 200.79104187182466
# differential_evolution step 81: f(x)= 200.79104187182466
# differential_evolution step 82: f(x)= 200.79104187182466
# differential_evolution step 83: f(x)= 200.79104187182466
# differential_evolution step 84: f(x)= 200.79104187182466
# differential_evolution step 85: f(x)= 200.79104187182466
# differential_evolution step 86: f(x)= 200.79104187182466
# differential_evolution step 87: f(x)= 200.79104187182466
# differential_evolution step 88: f(x)= 200.79104187182466
# differential_evolution step 89: f(x)= 200.79104187182466
# differential_evolution step 90: f(x)= 197.77415163154953
# differential_evolution step 91: f(x)= 197.77415163154953
# differential_evolution step 92: f(x)= 197.77415163154953
# differential_evolution step 93: f(x)= 197.77415163154953
# differential_evolution step 94: f(x)= 197.77415163154953
# differential_evolution step 95: f(x)= 197.77415163154953
# differential_evolution step 96: f(x)= 197.77415163154953
# differential_evolution step 97: f(x)= 197.77415163154953
# differential_evolution step 98: f(x)= 184.72037024929008
# differential_evolution step 99: f(x)= 184.72037024929008
# differential_evolution step 100: f(x)= 171.0762231784432
# differential_evolution step 101: f(x)= 171.0762231784432
# differential_evolution step 102: f(x)= 171.0762231784432
# differential_evolution step 103: f(x)= 154.0834223254662
# differential_evolution step 104: f(x)= 154.0834223254662
# differential_evolution step 105: f(x)= 147.77927560255415
# differential_evolution step 106: f(x)= 147.77927560255415
# differential_evolution step 107: f(x)= 147.77927560255415
# differential_evolution step 108: f(x)= 147.77927560255415
# differential_evolution step 109: f(x)= 147.77927560255415
# differential_evolution step 110: f(x)= 122.08126585525635
# differential_evolution step 111: f(x)= 122.08126585525635
# differential_evolution step 112: f(x)= 122.08126585525635
# differential_evolution step 113: f(x)= 122.08126585525635
# differential_evolution step 114: f(x)= 122.08126585525635
# differential_evolution step 115: f(x)= 122.08126585525635
# differential_evolution step 116: f(x)= 122.08126585525635
# differential_evolution step 117: f(x)= 122.08126585525635
# differential_evolution step 118: f(x)= 122.08126585525635
# differential_evolution step 119: f(x)= 122.08126585525635
# differential_evolution step 120: f(x)= 122.08126585525635
# differential_evolution step 121: f(x)= 122.08126585525635
# differential_evolution step 122: f(x)= 122.08126585525635
# differential_evolution step 123: f(x)= 122.08126585525635
# differential_evolution step 124: f(x)= 122.08126585525635
# differential_evolution step 125: f(x)= 122.08126585525635
# differential_evolution step 126: f(x)= 122.08126585525635
# differential_evolution step 127: f(x)= 122.08126585525635
# differential_evolution step 128: f(x)= 122.08126585525635
# differential_evolution step 129: f(x)= 122.08126585525635
# differential_evolution step 130: f(x)= 122.08126585525635
# differential_evolution step 131: f(x)= 122.08126585525635
# differential_evolution step 132: f(x)= 122.08126585525635
# differential_evolution step 133: f(x)= 122.08126585525635
# differential_evolution step 134: f(x)= 122.08126585525635
# differential_evolution step 135: f(x)= 122.08126585525635
# differential_evolution step 136: f(x)= 122.08126585525635
# differential_evolution step 137: f(x)= 122.08126585525635
# differential_evolution step 138: f(x)= 122.08126585525635
# differential_evolution step 139: f(x)= 122.08126585525635
# differential_evolution step 140: f(x)= 122.08126585525635
# differential_evolution step 141: f(x)= 122.08126585525635
# differential_evolution step 142: f(x)= 122.08126585525635
# differential_evolution step 143: f(x)= 122.08126585525635
# differential_evolution step 144: f(x)= 122.08126585525635
# differential_evolution step 145: f(x)= 122.08126585525635
# differential_evolution step 146: f(x)= 122.08126585525635
# differential_evolution step 147: f(x)= 122.08126585525635
# differential_evolution step 148: f(x)= 122.08126585525635
# differential_evolution step 149: f(x)= 122.08126585525635
# differential_evolution step 150: f(x)= 122.08126585525635
# differential_evolution step 151: f(x)= 122.08126585525635
# differential_evolution step 152: f(x)= 122.08126585525635
# differential_evolution step 153: f(x)= 122.08126585525635
# differential_evolution step 154: f(x)= 122.08126585525635
# differential_evolution step 155: f(x)= 122.08126585525635
# differential_evolution step 156: f(x)= 115.68194624258842
# differential_evolution step 157: f(x)= 115.68194624258842
# differential_evolution step 158: f(x)= 115.68194624258842
# differential_evolution step 159: f(x)= 115.68194624258842
# differential_evolution step 160: f(x)= 115.68194624258842
# differential_evolution step 161: f(x)= 115.3549557710295
# differential_evolution step 162: f(x)= 115.3549557710295
# differential_evolution step 163: f(x)= 115.3549557710295
# differential_evolution step 164: f(x)= 115.3549557710295
# differential_evolution step 165: f(x)= 115.3549557710295
# differential_evolution step 166: f(x)= 115.3549557710295
# differential_evolution step 167: f(x)= 115.3549557710295
# differential_evolution step 168: f(x)= 115.3549557710295
# differential_evolution step 169: f(x)= 115.3549557710295
# differential_evolution step 170: f(x)= 115.3549557710295
# differential_evolution step 171: f(x)= 115.3549557710295
# differential_evolution step 172: f(x)= 115.3549557710295
# differential_evolution step 173: f(x)= 115.3549557710295
# differential_evolution step 174: f(x)= 115.3549557710295
# differential_evolution step 175: f(x)= 115.3549557710295
# differential_evolution step 176: f(x)= 115.3549557710295
# differential_evolution step 177: f(x)= 114.24690252398456
# differential_evolution step 178: f(x)= 112.52882216027164
# differential_evolution step 179: f(x)= 112.52882216027164
# differential_evolution step 180: f(x)= 112.52882216027164
# differential_evolution step 181: f(x)= 112.52882216027164
# differential_evolution step 182: f(x)= 112.52882216027164
# differential_evolution step 183: f(x)= 111.67051406652118
# differential_evolution step 184: f(x)= 111.67051406652118
# differential_evolution step 185: f(x)= 111.67051406652118
# differential_evolution step 186: f(x)= 111.67051406652118
# differential_evolution step 187: f(x)= 111.67051406652118
# differential_evolution step 188: f(x)= 111.05856782729488
# differential_evolution step 189: f(x)= 110.71882398282943
# differential_evolution step 190: f(x)= 110.71882398282943
# differential_evolution step 191: f(x)= 110.71882398282943
# differential_evolution step 192: f(x)= 110.50658878873426
# differential_evolution step 193: f(x)= 110.50658878873426
# differential_evolution step 194: f(x)= 108.10705989262605
# differential_evolution step 195: f(x)= 108.10705989262605
# differential_evolution step 196: f(x)= 108.10705989262605
# differential_evolution step 197: f(x)= 108.10705989262605
# differential_evolution step 198: f(x)= 108.10705989262605
# differential_evolution step 199: f(x)= 108.10705989262605
# differential_evolution step 200: f(x)= 108.10705989262605
# differential_evolution step 201: f(x)= 108.10705989262605
# differential_evolution step 202: f(x)= 108.10705989262605
# differential_evolution step 203: f(x)= 108.10705989262605
# differential_evolution step 204: f(x)= 108.10705989262605
# differential_evolution step 205: f(x)= 108.10705989262605
# differential_evolution step 206: f(x)= 108.10705989262605
# differential_evolution step 207: f(x)= 108.10705989262605
# differential_evolution step 208: f(x)= 108.10705989262605
# differential_evolution step 209: f(x)= 108.10705989262605
# differential_evolution step 210: f(x)= 108.10705989262605
# differential_evolution step 211: f(x)= 108.10705989262605
# differential_evolution step 212: f(x)= 108.10705989262605
# differential_evolution step 213: f(x)= 108.10705989262605
# differential_evolution step 214: f(x)= 108.10705989262605
# differential_evolution step 215: f(x)= 108.10705989262605
# differential_evolution step 216: f(x)= 108.10705989262605
# differential_evolution step 217: f(x)= 108.10705989262605
# differential_evolution step 218: f(x)= 108.10705989262605
# differential_evolution step 219: f(x)= 108.10705989262605
# differential_evolution step 220: f(x)= 108.10705989262605
# differential_evolution step 221: f(x)= 108.10705989262605
# differential_evolution step 222: f(x)= 108.10705989262605
# differential_evolution step 223: f(x)= 107.9895379687899
# differential_evolution step 224: f(x)= 107.9895379687899
# differential_evolution step 225: f(x)= 107.9895379687899
# differential_evolution step 226: f(x)= 107.9895379687899
# differential_evolution step 227: f(x)= 107.9895379687899
# differential_evolution step 228: f(x)= 107.9895379687899
# differential_evolution step 229: f(x)= 107.9895379687899
# differential_evolution step 230: f(x)= 107.9895379687899
# differential_evolution step 231: f(x)= 107.9895379687899
# differential_evolution step 232: f(x)= 107.9895379687899
# differential_evolution step 233: f(x)= 107.9895379687899
# differential_evolution step 234: f(x)= 107.67332696800374
# differential_evolution step 235: f(x)= 107.67332696800374
# differential_evolution step 236: f(x)= 107.61031007384783
# differential_evolution step 237: f(x)= 107.61031007384783
# differential_evolution step 238: f(x)= 107.61031007384783
# differential_evolution step 239: f(x)= 107.61031007384783
# differential_evolution step 240: f(x)= 107.61031007384783
# differential_evolution step 241: f(x)= 107.61031007384783
# differential_evolution step 242: f(x)= 106.4747483456448
# differential_evolution step 243: f(x)= 106.4747483456448
# differential_evolution step 244: f(x)= 106.4747483456448
# differential_evolution step 245: f(x)= 106.4747483456448
# differential_evolution step 246: f(x)= 106.4747483456448
# differential_evolution step 247: f(x)= 106.4747483456448
# differential_evolution step 248: f(x)= 106.4747483456448
# differential_evolution step 249: f(x)= 106.4747483456448
# differential_evolution step 250: f(x)= 106.4747483456448
# differential_evolution step 251: f(x)= 106.4747483456448
# differential_evolution step 252: f(x)= 106.4747483456448
# differential_evolution step 253: f(x)= 106.4747483456448
# differential_evolution step 254: f(x)= 106.4747483456448
# differential_evolution step 255: f(x)= 106.4747483456448
# differential_evolution step 256: f(x)= 106.4747483456448
# differential_evolution step 257: f(x)= 106.4747483456448
# differential_evolution step 258: f(x)= 106.4747483456448
# differential_evolution step 259: f(x)= 106.4747483456448
# differential_evolution step 260: f(x)= 106.4747483456448
# differential_evolution step 261: f(x)= 106.4747483456448
# differential_evolution step 262: f(x)= 106.4747483456448
# differential_evolution step 263: f(x)= 106.4747483456448
# differential_evolution step 264: f(x)= 106.4747483456448
# differential_evolution step 265: f(x)= 106.4747483456448
# differential_evolution step 266: f(x)= 106.4747483456448
# differential_evolution step 267: f(x)= 106.4747483456448
# differential_evolution step 268: f(x)= 106.4747483456448
# differential_evolution step 269: f(x)= 106.4747483456448
# differential_evolution step 270: f(x)= 106.4747483456448
# differential_evolution step 271: f(x)= 106.35032302661114
# differential_evolution step 272: f(x)= 106.35032302661114
# differential_evolution step 273: f(x)= 106.35032302661114
# differential_evolution step 274: f(x)= 106.35032302661114
# differential_evolution step 275: f(x)= 106.35032302661114
# differential_evolution step 276: f(x)= 106.35032302661114
# differential_evolution step 277: f(x)= 106.35032302661114
# differential_evolution step 278: f(x)= 106.35032302661114
# differential_evolution step 279: f(x)= 106.35032302661114
# differential_evolution step 280: f(x)= 106.35032302661114
# differential_evolution step 281: f(x)= 106.35032302661114
# differential_evolution step 282: f(x)= 106.35032302661114
# differential_evolution step 283: f(x)= 106.35032302661114
# differential_evolution step 284: f(x)= 106.35032302661114
# differential_evolution step 285: f(x)= 105.91810686163016
# differential_evolution step 286: f(x)= 105.91810686163016
# differential_evolution step 287: f(x)= 105.91810686163016
# differential_evolution step 288: f(x)= 105.91810686163016
# differential_evolution step 289: f(x)= 105.91810686163016
# differential_evolution step 290: f(x)= 105.91810686163016
# differential_evolution step 291: f(x)= 105.91810686163016
# differential_evolution step 292: f(x)= 105.91810686163016
# differential_evolution step 293: f(x)= 105.91810686163016
# differential_evolution step 294: f(x)= 105.91810686163016
# differential_evolution step 295: f(x)= 105.91810686163016
# differential_evolution step 296: f(x)= 105.91810686163016
# differential_evolution step 297: f(x)= 105.91810686163016
# differential_evolution step 298: f(x)= 105.31899411294131
# differential_evolution step 299: f(x)= 105.31899411294131
# differential_evolution step 300: f(x)= 105.31899411294131
# differential_evolution step 301: f(x)= 105.31899411294131
# differential_evolution step 302: f(x)= 105.31899411294131
# differential_evolution step 303: f(x)= 104.7044750515069
# differential_evolution step 304: f(x)= 104.7044750515069
# differential_evolution step 305: f(x)= 104.7044750515069
# differential_evolution step 306: f(x)= 104.7044750515069
# differential_evolution step 307: f(x)= 104.7044750515069
# differential_evolution step 308: f(x)= 104.7044750515069
# differential_evolution step 309: f(x)= 104.7044750515069
# differential_evolution step 310: f(x)= 104.7044750515069
# differential_evolution step 311: f(x)= 104.7044750515069
# differential_evolution step 312: f(x)= 104.7044750515069
# differential_evolution step 313: f(x)= 104.7044750515069
# differential_evolution step 314: f(x)= 104.7044750515069
# differential_evolution step 315: f(x)= 104.7044750515069
# differential_evolution step 316: f(x)= 104.7044750515069
# differential_evolution step 317: f(x)= 104.7044750515069
# differential_evolution step 318: f(x)= 104.7044750515069
# differential_evolution step 319: f(x)= 104.7044750515069
# differential_evolution step 320: f(x)= 104.7044750515069
# differential_evolution step 321: f(x)= 104.7044750515069
# differential_evolution step 322: f(x)= 104.7044750515069
# differential_evolution step 323: f(x)= 104.7044750515069
# differential_evolution step 324: f(x)= 104.7044750515069
# differential_evolution step 325: f(x)= 104.7044750515069
# differential_evolution step 326: f(x)= 104.3345067121147
# differential_evolution step 327: f(x)= 104.3345067121147
# differential_evolution step 328: f(x)= 104.3345067121147
# differential_evolution step 329: f(x)= 104.3345067121147
# differential_evolution step 330: f(x)= 104.3345067121147
# differential_evolution step 331: f(x)= 104.3345067121147
# differential_evolution step 332: f(x)= 104.3345067121147
# differential_evolution step 333: f(x)= 104.3345067121147
# differential_evolution step 334: f(x)= 104.3345067121147
# differential_evolution step 335: f(x)= 104.3345067121147
# differential_evolution step 336: f(x)= 104.3345067121147
# differential_evolution step 337: f(x)= 104.3345067121147
# differential_evolution step 338: f(x)= 104.3345067121147
# differential_evolution step 339: f(x)= 104.3345067121147
# differential_evolution step 340: f(x)= 104.3345067121147
# differential_evolution step 341: f(x)= 104.3345067121147
# differential_evolution step 342: f(x)= 104.3345067121147
# differential_evolution step 343: f(x)= 104.3345067121147
# differential_evolution step 344: f(x)= 104.3345067121147
# differential_evolution step 345: f(x)= 104.3345067121147
# differential_evolution step 346: f(x)= 104.3345067121147
# differential_evolution step 347: f(x)= 104.3345067121147
# differential_evolution step 348: f(x)= 104.3345067121147
# differential_evolution step 349: f(x)= 104.3345067121147
# differential_evolution step 350: f(x)= 104.3345067121147
# differential_evolution step 351: f(x)= 104.3345067121147
# differential_evolution step 352: f(x)= 104.3345067121147
# differential_evolution step 353: f(x)= 104.3345067121147
# differential_evolution step 354: f(x)= 104.3345067121147
# differential_evolution step 355: f(x)= 104.3345067121147
# differential_evolution step 356: f(x)= 104.31172654137173
# differential_evolution step 357: f(x)= 104.31172654137173
# differential_evolution step 358: f(x)= 104.31172654137173
# differential_evolution step 359: f(x)= 104.31172654137173
# differential_evolution step 360: f(x)= 104.31172654137173
# differential_evolution step 361: f(x)= 104.31172654137173
# differential_evolution step 362: f(x)= 104.31172654137173
# differential_evolution step 363: f(x)= 104.31172654137173
# differential_evolution step 364: f(x)= 104.1207994900459
# differential_evolution step 365: f(x)= 104.1207994900459
# differential_evolution step 366: f(x)= 104.1207994900459
# differential_evolution step 367: f(x)= 104.1207994900459
# differential_evolution step 368: f(x)= 104.1207994900459
# differential_evolution step 369: f(x)= 103.59602558091404
# differential_evolution step 370: f(x)= 103.59602558091404
# differential_evolution step 371: f(x)= 103.59602558091404
# differential_evolution step 372: f(x)= 103.59602558091404
# differential_evolution step 373: f(x)= 103.59602558091404
# differential_evolution step 374: f(x)= 103.30415989142777
# differential_evolution step 375: f(x)= 103.30415989142777
# differential_evolution step 376: f(x)= 103.30415989142777
# differential_evolution step 377: f(x)= 103.30415989142777
# differential_evolution step 378: f(x)= 103.30415989142777
# differential_evolution step 379: f(x)= 103.30415989142777
# differential_evolution step 380: f(x)= 103.30415989142777
# differential_evolution step 381: f(x)= 103.30415989142777
# differential_evolution step 382: f(x)= 103.30415989142777
# differential_evolution step 383: f(x)= 103.30415989142777
# differential_evolution step 384: f(x)= 103.30415989142777
# differential_evolution step 385: f(x)= 103.30415989142777
# differential_evolution step 386: f(x)= 103.30415989142777
# differential_evolution step 387: f(x)= 103.30415989142777
# differential_evolution step 388: f(x)= 103.30415989142777
# differential_evolution step 389: f(x)= 103.30415989142777
# differential_evolution step 390: f(x)= 103.30415989142777
# differential_evolution step 391: f(x)= 103.30415989142777
# differential_evolution step 392: f(x)= 103.21818032470215
# differential_evolution step 393: f(x)= 103.21818032470215
# differential_evolution step 394: f(x)= 103.21818032470215
# differential_evolution step 395: f(x)= 103.03740680494141
# differential_evolution step 396: f(x)= 103.03740680494141
# differential_evolution step 397: f(x)= 103.03740680494141
# differential_evolution step 398: f(x)= 103.03740680494141
# differential_evolution step 399: f(x)= 102.96618996290286
# differential_evolution step 400: f(x)= 102.96618996290286
# differential_evolution step 401: f(x)= 102.96618996290286
# differential_evolution step 402: f(x)= 102.96618996290286
# differential_evolution step 403: f(x)= 102.96618996290286
# differential_evolution step 404: f(x)= 102.96618996290286
# differential_evolution step 405: f(x)= 102.96618996290286
# differential_evolution step 406: f(x)= 102.75528495350684
# differential_evolution step 407: f(x)= 102.3915392354661
# differential_evolution step 408: f(x)= 102.3915392354661
# differential_evolution step 409: f(x)= 102.3915392354661
# differential_evolution step 410: f(x)= 102.3915392354661
# differential_evolution step 411: f(x)= 102.3915392354661
# differential_evolution step 412: f(x)= 102.3915392354661
# differential_evolution step 413: f(x)= 102.3915392354661
# differential_evolution step 414: f(x)= 102.3915392354661
# differential_evolution step 415: f(x)= 102.3915392354661
# differential_evolution step 416: f(x)= 102.3915392354661
# differential_evolution step 417: f(x)= 102.3915392354661
# differential_evolution step 418: f(x)= 102.3915392354661
# differential_evolution step 419: f(x)= 102.3915392354661
# differential_evolution step 420: f(x)= 102.36994238103325
# differential_evolution step 421: f(x)= 102.36994238103325
# differential_evolution step 422: f(x)= 101.96101912046203
# differential_evolution step 423: f(x)= 101.95914171921734
# differential_evolution step 424: f(x)= 101.44473126071486
# differential_evolution step 425: f(x)= 101.44473126071486
# differential_evolution step 426: f(x)= 101.44473126071486
# differential_evolution step 427: f(x)= 101.44473126071486
# differential_evolution step 428: f(x)= 101.44473126071486
# differential_evolution step 429: f(x)= 101.44473126071486
# differential_evolution step 430: f(x)= 101.41585923954547
# differential_evolution step 431: f(x)= 100.76134033440046
# differential_evolution step 432: f(x)= 100.42482639681762
# differential_evolution step 433: f(x)= 100.42482639681762
# differential_evolution step 434: f(x)= 100.42482639681762
# differential_evolution step 435: f(x)= 100.42482639681762
# differential_evolution step 436: f(x)= 100.42482639681762
# differential_evolution step 437: f(x)= 100.42482639681762
# differential_evolution step 438: f(x)= 100.42482639681762
# differential_evolution step 439: f(x)= 100.42482639681762
# differential_evolution step 440: f(x)= 100.42482639681762
# differential_evolution step 441: f(x)= 100.42482639681762
# differential_evolution step 442: f(x)= 100.42482639681762
# differential_evolution step 443: f(x)= 100.42482639681762
# differential_evolution step 444: f(x)= 100.42482639681762
# differential_evolution step 445: f(x)= 100.42482639681762
# differential_evolution step 446: f(x)= 100.42482639681762
# differential_evolution step 447: f(x)= 100.42482639681762
# differential_evolution step 448: f(x)= 100.42482639681762
# differential_evolution step 449: f(x)= 100.42482639681762
# differential_evolution step 450: f(x)= 100.42482639681762
# differential_evolution step 451: f(x)= 100.42482639681762
# differential_evolution step 452: f(x)= 100.42482639681762
# differential_evolution step 453: f(x)= 100.42482639681762
# differential_evolution step 454: f(x)= 100.42482639681762
# differential_evolution step 455: f(x)= 100.04091117563954
# differential_evolution step 456: f(x)= 99.6515697805917
# differential_evolution step 457: f(x)= 98.90385129274902
# differential_evolution step 458: f(x)= 98.13916460265322
# differential_evolution step 459: f(x)= 98.13916460265322
# differential_evolution step 460: f(x)= 98.13916460265322
# differential_evolution step 461: f(x)= 98.13916460265322
# differential_evolution step 462: f(x)= 98.13916460265322
# differential_evolution step 463: f(x)= 98.13916460265322
# differential_evolution step 464: f(x)= 98.13916460265322
# differential_evolution step 465: f(x)= 98.00560507646107
# differential_evolution step 466: f(x)= 98.00560507646107
# differential_evolution step 467: f(x)= 97.25372694937948
# differential_evolution step 468: f(x)= 97.25372694937948
# differential_evolution step 469: f(x)= 97.25372694937948
# differential_evolution step 470: f(x)= 97.25372694937948
# differential_evolution step 471: f(x)= 97.25372694937948
# differential_evolution step 472: f(x)= 97.17942857614334
# differential_evolution step 473: f(x)= 97.17942857614334
# differential_evolution step 474: f(x)= 97.17942857614334
# differential_evolution step 475: f(x)= 97.17942857614334
# differential_evolution step 476: f(x)= 97.17942857614334
# differential_evolution step 477: f(x)= 97.17942857614334
# differential_evolution step 478: f(x)= 97.17942857614334
# differential_evolution step 479: f(x)= 97.17942857614334
# differential_evolution step 480: f(x)= 97.17942857614334
# differential_evolution step 481: f(x)= 97.17942857614334
# differential_evolution step 482: f(x)= 97.17942857614334
# differential_evolution step 483: f(x)= 96.58316569556983
# differential_evolution step 484: f(x)= 96.58316569556983
# differential_evolution step 485: f(x)= 96.58316569556983
# differential_evolution step 486: f(x)= 96.46516858760437
# differential_evolution step 487: f(x)= 96.46516858760437
# differential_evolution step 488: f(x)= 96.40668723945767
# differential_evolution step 489: f(x)= 96.05768715249754
# differential_evolution step 490: f(x)= 96.05768715249754
# differential_evolution step 491: f(x)= 95.9958622891689
# differential_evolution step 492: f(x)= 95.9958622891689
# differential_evolution step 493: f(x)= 95.9958622891689
# differential_evolution step 494: f(x)= 94.81430302411478
# differential_evolution step 495: f(x)= 94.81430302411478
# differential_evolution step 496: f(x)= 94.81430302411478
# differential_evolution step 497: f(x)= 94.81430302411478
# differential_evolution step 498: f(x)= 94.58029164295539
# differential_evolution step 499: f(x)= 94.58029164295539
# differential_evolution step 500: f(x)= 94.58029164295539
# differential_evolution step 501: f(x)= 94.58029164295539
# differential_evolution step 502: f(x)= 94.58029164295539
# differential_evolution step 503: f(x)= 94.58029164295539
# differential_evolution step 504: f(x)= 94.58029164295539
# differential_evolution step 505: f(x)= 94.58029164295539
# differential_evolution step 506: f(x)= 94.31037183268629
# differential_evolution step 507: f(x)= 93.60611152481523
# differential_evolution step 508: f(x)= 93.30784289632129
# differential_evolution step 509: f(x)= 93.30784289632129
# differential_evolution step 510: f(x)= 93.30784289632129
# differential_evolution step 511: f(x)= 92.07936288759657
# differential_evolution step 512: f(x)= 92.07936288759657
# differential_evolution step 513: f(x)= 90.02837408148332
# differential_evolution step 514: f(x)= 90.02837408148332
# differential_evolution step 515: f(x)= 90.02837408148332
# differential_evolution step 516: f(x)= 90.02026254094707
# differential_evolution step 517: f(x)= 90.02026254094707
# differential_evolution step 518: f(x)= 90.02026254094707
# differential_evolution step 519: f(x)= 89.94894592354294
# differential_evolution step 520: f(x)= 89.94894592354294
# differential_evolution step 521: f(x)= 89.52089507206328
# differential_evolution step 522: f(x)= 89.52089507206328
# differential_evolution step 523: f(x)= 89.52089507206328
# differential_evolution step 524: f(x)= 89.52089507206328
# differential_evolution step 525: f(x)= 89.52089507206328
# differential_evolution step 526: f(x)= 89.52089507206328
# differential_evolution step 527: f(x)= 89.52089507206328
# differential_evolution step 528: f(x)= 89.52089507206328
# differential_evolution step 529: f(x)= 89.52089507206328
# differential_evolution step 530: f(x)= 89.52089507206328
# differential_evolution step 531: f(x)= 89.52089507206328
# differential_evolution step 532: f(x)= 89.52089507206328
# differential_evolution step 533: f(x)= 89.03520472129834
# differential_evolution step 534: f(x)= 89.03520472129834
# differential_evolution step 535: f(x)= 89.03520472129834
# differential_evolution step 536: f(x)= 89.03520472129834
# differential_evolution step 537: f(x)= 89.03520472129834
# differential_evolution step 538: f(x)= 89.03520472129834
# differential_evolution step 539: f(x)= 89.03520472129834
# differential_evolution step 540: f(x)= 87.89155005858072
# differential_evolution step 541: f(x)= 87.89155005858072
# differential_evolution step 542: f(x)= 87.89155005858072
# differential_evolution step 543: f(x)= 87.89155005858072
# differential_evolution step 544: f(x)= 87.89155005858072
# differential_evolution step 545: f(x)= 87.89155005858072
# differential_evolution step 546: f(x)= 87.89155005858072
# differential_evolution step 547: f(x)= 87.65917045982657
# differential_evolution step 548: f(x)= 87.65917045982657
# differential_evolution step 549: f(x)= 87.65917045982657
# differential_evolution step 550: f(x)= 87.65917045982657
# differential_evolution step 551: f(x)= 87.65917045982657
# differential_evolution step 552: f(x)= 87.19557062902564
# differential_evolution step 553: f(x)= 87.19557062902564
# differential_evolution step 554: f(x)= 87.19557062902564
# differential_evolution step 555: f(x)= 87.19557062902564
# differential_evolution step 556: f(x)= 87.19557062902564
# differential_evolution step 557: f(x)= 87.19557062902564
# differential_evolution step 558: f(x)= 87.19557062902564
# differential_evolution step 559: f(x)= 87.19557062902564
# differential_evolution step 560: f(x)= 86.72370331786284
# differential_evolution step 561: f(x)= 86.72370331786284
# differential_evolution step 562: f(x)= 86.72370331786284
# differential_evolution step 563: f(x)= 86.72370331786284
# differential_evolution step 564: f(x)= 86.72370331786284
# differential_evolution step 565: f(x)= 86.72370331786284
# differential_evolution step 566: f(x)= 86.72370331786284
# differential_evolution step 567: f(x)= 86.11030603480067
# differential_evolution step 568: f(x)= 86.11030603480067
# differential_evolution step 569: f(x)= 86.11030603480067
# differential_evolution step 570: f(x)= 86.11030603480067
# differential_evolution step 571: f(x)= 86.11030603480067
# differential_evolution step 572: f(x)= 86.11030603480067
# differential_evolution step 573: f(x)= 86.11030603480067
# differential_evolution step 574: f(x)= 86.11030603480067
# differential_evolution step 575: f(x)= 86.11030603480067
# differential_evolution step 576: f(x)= 86.11030603480067
# differential_evolution step 577: f(x)= 86.11030603480067
# differential_evolution step 578: f(x)= 86.11030603480067
# differential_evolution step 579: f(x)= 86.11030603480067
# differential_evolution step 580: f(x)= 86.11030603480067
# differential_evolution step 581: f(x)= 86.11030603480067
# differential_evolution step 582: f(x)= 86.11030603480067
# differential_evolution step 583: f(x)= 86.11030603480067
# differential_evolution step 584: f(x)= 86.11030603480067
# differential_evolution step 585: f(x)= 86.11030603480067
# differential_evolution step 586: f(x)= 86.11030603480067
# differential_evolution step 587: f(x)= 86.1088960233802
# differential_evolution step 588: f(x)= 86.1088960233802
# differential_evolution step 589: f(x)= 86.1088960233802
# differential_evolution step 590: f(x)= 86.1088960233802
# differential_evolution step 591: f(x)= 86.0731792082984
# differential_evolution step 592: f(x)= 86.0731792082984
# differential_evolution step 593: f(x)= 86.0731792082984
# differential_evolution step 594: f(x)= 86.0731792082984
# differential_evolution step 595: f(x)= 85.92611532842913
# differential_evolution step 596: f(x)= 85.8824036978293
# differential_evolution step 597: f(x)= 85.8824036978293
# differential_evolution step 598: f(x)= 85.8824036978293
# differential_evolution step 599: f(x)= 85.8824036978293
# differential_evolution step 600: f(x)= 85.8824036978293
# differential_evolution step 601: f(x)= 85.51326653127157
# differential_evolution step 602: f(x)= 85.51326653127157
# differential_evolution step 603: f(x)= 85.51326653127157
# differential_evolution step 604: f(x)= 85.51326653127157
# differential_evolution step 605: f(x)= 85.51326653127157
# differential_evolution step 606: f(x)= 85.51326653127157
# differential_evolution step 607: f(x)= 85.51326653127157
# differential_evolution step 608: f(x)= 85.51326653127157
# differential_evolution step 609: f(x)= 85.51326653127157
# differential_evolution step 610: f(x)= 85.51326653127157
# differential_evolution step 611: f(x)= 85.51326653127157
# differential_evolution step 612: f(x)= 85.51326653127157
# differential_evolution step 613: f(x)= 85.51326653127157
# differential_evolution step 614: f(x)= 85.51326653127157
# differential_evolution step 615: f(x)= 85.51326653127157
# differential_evolution step 616: f(x)= 85.51326653127157
# differential_evolution step 617: f(x)= 85.51326653127157
# differential_evolution step 618: f(x)= 85.51326653127157
# differential_evolution step 619: f(x)= 85.51326653127157
# differential_evolution step 620: f(x)= 85.51326653127157
# differential_evolution step 621: f(x)= 85.51326653127157
# differential_evolution step 622: f(x)= 85.51326653127157
# differential_evolution step 623: f(x)= 85.51326653127157
# differential_evolution step 624: f(x)= 85.48200963648561
# differential_evolution step 625: f(x)= 85.48200963648561
# differential_evolution step 626: f(x)= 85.47181337081165
# differential_evolution step 627: f(x)= 85.47181337081165
# differential_evolution step 628: f(x)= 85.47181337081165
# differential_evolution step 629: f(x)= 85.47181337081165
# differential_evolution step 630: f(x)= 85.47181337081165
# differential_evolution step 631: f(x)= 85.47181337081165
# differential_evolution step 632: f(x)= 85.47181337081165
# differential_evolution step 633: f(x)= 85.47181337081165
# differential_evolution step 634: f(x)= 85.47181337081165
# differential_evolution step 635: f(x)= 85.39850507970655
# differential_evolution step 636: f(x)= 85.39850507970655
# differential_evolution step 637: f(x)= 85.39850507970655
# differential_evolution step 638: f(x)= 85.39850507970655
# differential_evolution step 639: f(x)= 85.39850507970655
# differential_evolution step 640: f(x)= 85.39850507970655
# differential_evolution step 641: f(x)= 85.39850507970655
# differential_evolution step 642: f(x)= 85.38250853398718
# differential_evolution step 643: f(x)= 85.38250853398718
# differential_evolution step 644: f(x)= 85.38250853398718
# differential_evolution step 645: f(x)= 85.38250853398718
# differential_evolution step 646: f(x)= 85.38250853398718
# differential_evolution step 647: f(x)= 85.38250853398718
# differential_evolution step 648: f(x)= 85.38088507865938
# differential_evolution step 649: f(x)= 85.38088507865938
# differential_evolution step 650: f(x)= 85.38088507865938
# differential_evolution step 651: f(x)= 85.38088507865938
# differential_evolution step 652: f(x)= 85.38088507865938
# differential_evolution step 653: f(x)= 85.38088507865938
# differential_evolution step 654: f(x)= 85.38088507865938
# differential_evolution step 655: f(x)= 85.38088507865938
# differential_evolution step 656: f(x)= 85.38088507865938
# differential_evolution step 657: f(x)= 85.38088507865938
# differential_evolution step 658: f(x)= 85.38088507865938
# differential_evolution step 659: f(x)= 85.38088507865938
# differential_evolution step 660: f(x)= 85.38088507865938
# differential_evolution step 661: f(x)= 85.38088507865938
# differential_evolution step 662: f(x)= 85.35535986963305
# differential_evolution step 663: f(x)= 85.35535986963305
# differential_evolution step 664: f(x)= 85.35535986963305
# differential_evolution step 665: f(x)= 85.35535986963305
# differential_evolution step 666: f(x)= 85.35535986963305
# differential_evolution step 667: f(x)= 85.35535986963305
# differential_evolution step 668: f(x)= 85.35535986963305
# differential_evolution step 669: f(x)= 85.35535986963305
# differential_evolution step 670: f(x)= 85.35535986963305
# differential_evolution step 671: f(x)= 85.35535986963305
# differential_evolution step 672: f(x)= 85.35535986963305
# differential_evolution step 673: f(x)= 85.35535986963305
# differential_evolution step 674: f(x)= 85.35535986963305
# differential_evolution step 675: f(x)= 85.35535986963305
# differential_evolution step 676: f(x)= 85.35535986963305
# differential_evolution step 677: f(x)= 85.33994847926648
# differential_evolution step 678: f(x)= 85.33994847926648
# differential_evolution step 679: f(x)= 85.33994847926648
# differential_evolution step 680: f(x)= 85.33994847926648
# differential_evolution step 681: f(x)= 85.33994847926648
# differential_evolution step 682: f(x)= 85.33994847926648
# differential_evolution step 683: f(x)= 85.33994847926648
# differential_evolution step 684: f(x)= 85.31665414228081
# differential_evolution step 685: f(x)= 85.31665414228081
# differential_evolution step 686: f(x)= 85.31665414228081
# differential_evolution step 687: f(x)= 85.31665414228081
# differential_evolution step 688: f(x)= 85.31665414228081
# differential_evolution step 689: f(x)= 85.31665414228081
# differential_evolution step 690: f(x)= 85.31665414228081
# differential_evolution step 691: f(x)= 85.31665414228081
# differential_evolution step 692: f(x)= 85.31665414228081
# differential_evolution step 693: f(x)= 85.31665414228081
# differential_evolution step 694: f(x)= 85.30314998920744
# differential_evolution step 695: f(x)= 85.30314998920744
# differential_evolution step 696: f(x)= 85.30314998920744
# differential_evolution step 697: f(x)= 85.30314998920744
# differential_evolution step 698: f(x)= 85.30314998920744
# differential_evolution step 699: f(x)= 85.30314998920744
# differential_evolution step 700: f(x)= 85.30314998920744
# differential_evolution step 701: f(x)= 85.30314998920744
# differential_evolution step 702: f(x)= 85.30314998920744
# differential_evolution step 703: f(x)= 85.30314998920744
# differential_evolution step 704: f(x)= 85.30314998920744
# differential_evolution step 705: f(x)= 85.30314998920744
# differential_evolution step 706: f(x)= 85.30314998920744
# differential_evolution step 707: f(x)= 85.30314998920744
# differential_evolution step 708: f(x)= 85.30314998920744
# differential_evolution step 709: f(x)= 85.30314998920744
# differential_evolution step 710: f(x)= 85.30314998920744
# differential_evolution step 711: f(x)= 85.30314998920744
# differential_evolution step 712: f(x)= 85.30314998920744
# differential_evolution step 713: f(x)= 85.30314998920744
# differential_evolution step 714: f(x)= 85.30314998920744
# differential_evolution step 715: f(x)= 85.30314998920744
# differential_evolution step 716: f(x)= 85.30314998920744
# differential_evolution step 717: f(x)= 85.30314998920744
# differential_evolution step 718: f(x)= 85.30314998920744
# differential_evolution step 719: f(x)= 85.30314998920744
# differential_evolution step 720: f(x)= 85.30314998920744
# differential_evolution step 721: f(x)= 85.30314998920744
# differential_evolution step 722: f(x)= 85.29399007517945
# differential_evolution step 723: f(x)= 85.29399007517945
# differential_evolution step 724: f(x)= 85.29399007517945
# differential_evolution step 725: f(x)= 85.29399007517945
# differential_evolution step 726: f(x)= 85.2890336695677
# differential_evolution step 727: f(x)= 85.2890336695677
# differential_evolution step 728: f(x)= 85.2890336695677
# differential_evolution step 729: f(x)= 85.2282917805892
# differential_evolution step 730: f(x)= 85.2282917805892
# differential_evolution step 731: f(x)= 85.2282917805892
# differential_evolution step 732: f(x)= 85.2282917805892
# differential_evolution step 733: f(x)= 85.2282917805892
# differential_evolution step 734: f(x)= 85.2282917805892
# differential_evolution step 735: f(x)= 85.2282917805892
# differential_evolution step 736: f(x)= 85.2282917805892
# differential_evolution step 737: f(x)= 85.2282917805892
# differential_evolution step 738: f(x)= 85.2282917805892
# differential_evolution step 739: f(x)= 85.2282917805892
# differential_evolution step 740: f(x)= 85.2282917805892
# differential_evolution step 741: f(x)= 85.2282917805892
# differential_evolution step 742: f(x)= 85.2282917805892
# differential_evolution step 743: f(x)= 85.2282917805892
# differential_evolution step 744: f(x)= 85.2282917805892
# differential_evolution step 745: f(x)= 85.2282917805892
# differential_evolution step 746: f(x)= 85.2282917805892
# differential_evolution step 747: f(x)= 85.2282917805892
# differential_evolution step 748: f(x)= 85.2282917805892
# differential_evolution step 749: f(x)= 85.2282917805892
# differential_evolution step 750: f(x)= 85.2282917805892
# differential_evolution step 751: f(x)= 85.2282917805892
# differential_evolution step 752: f(x)= 85.2282917805892
# differential_evolution step 753: f(x)= 85.2282917805892
# differential_evolution step 754: f(x)= 85.2282917805892
# differential_evolution step 755: f(x)= 85.2282917805892
# differential_evolution step 756: f(x)= 85.2282917805892
# differential_evolution step 757: f(x)= 85.2282917805892
# differential_evolution step 758: f(x)= 85.22371816207335
# differential_evolution step 759: f(x)= 85.22371816207335
# differential_evolution step 760: f(x)= 85.21255697162971
# differential_evolution step 761: f(x)= 85.21255697162971
# differential_evolution step 762: f(x)= 85.21255697162971
# differential_evolution step 763: f(x)= 85.21255697162971
# differential_evolution step 764: f(x)= 85.21255697162971
# differential_evolution step 765: f(x)= 85.21255697162971
# differential_evolution step 766: f(x)= 85.21255697162971
# differential_evolution step 767: f(x)= 85.21255697162971
# differential_evolution step 768: f(x)= 85.21255697162971
# differential_evolution step 769: f(x)= 85.20816597343098
# differential_evolution step 770: f(x)= 85.20816597343098
# differential_evolution step 771: f(x)= 85.2010710628145
# differential_evolution step 772: f(x)= 85.2010710628145
# differential_evolution step 773: f(x)= 85.2010710628145
# differential_evolution step 774: f(x)= 85.2010710628145
# differential_evolution step 775: f(x)= 85.2010710628145
# differential_evolution step 776: f(x)= 85.2010710628145
# differential_evolution step 777: f(x)= 85.2010710628145
# differential_evolution step 778: f(x)= 85.2010710628145
# differential_evolution step 779: f(x)= 85.2010710628145
# differential_evolution step 780: f(x)= 85.2010710628145
# differential_evolution step 781: f(x)= 85.2010710628145
# differential_evolution step 782: f(x)= 85.2010710628145
# differential_evolution step 783: f(x)= 85.2010710628145
# differential_evolution step 784: f(x)= 85.2010710628145
# differential_evolution step 785: f(x)= 85.2010710628145
# differential_evolution step 786: f(x)= 85.2010710628145
# differential_evolution step 787: f(x)= 85.2010710628145
# differential_evolution step 788: f(x)= 85.2010710628145
# differential_evolution step 789: f(x)= 85.19161704309721
# differential_evolution step 790: f(x)= 85.19161704309721
# differential_evolution step 791: f(x)= 85.19142788499924
# differential_evolution step 792: f(x)= 85.19142788499924
# differential_evolution step 793: f(x)= 85.19142788499924
# differential_evolution step 794: f(x)= 85.19142788499924
# differential_evolution step 795: f(x)= 85.19042112432749
# differential_evolution step 796: f(x)= 85.19042112432749
# differential_evolution step 797: f(x)= 85.19042112432749
# differential_evolution step 798: f(x)= 85.19042112432749
# differential_evolution step 799: f(x)= 85.19042112432749
# differential_evolution step 800: f(x)= 85.19042112432749
# differential_evolution step 801: f(x)= 85.19042112432749
# differential_evolution step 802: f(x)= 85.19042112432749
# differential_evolution step 803: f(x)= 85.19042112432749
# differential_evolution step 804: f(x)= 85.19042112432749
# differential_evolution step 805: f(x)= 85.19042112432749
# differential_evolution step 806: f(x)= 85.19042112432749
# differential_evolution step 807: f(x)= 85.19042112432749
# differential_evolution step 808: f(x)= 85.19042112432749
# differential_evolution step 809: f(x)= 85.19042112432749
# differential_evolution step 810: f(x)= 85.19042112432749
# differential_evolution step 811: f(x)= 85.19042112432749
# differential_evolution step 812: f(x)= 85.19042112432749
# differential_evolution step 813: f(x)= 85.18824793916035
# differential_evolution step 814: f(x)= 85.18824793916035
# differential_evolution step 815: f(x)= 85.18824793916035
# differential_evolution step 816: f(x)= 85.18824793916035
# differential_evolution step 817: f(x)= 85.18824793916035
# differential_evolution step 818: f(x)= 85.18824793916035
# differential_evolution step 819: f(x)= 85.18824793916035
# differential_evolution step 820: f(x)= 85.18824793916035
# differential_evolution step 821: f(x)= 85.18824793916035
# differential_evolution step 822: f(x)= 85.18824793916035
# differential_evolution step 823: f(x)= 85.18824793916035
# differential_evolution step 824: f(x)= 85.18824793916035
# differential_evolution step 825: f(x)= 85.18824793916035
# differential_evolution step 826: f(x)= 85.18824793916035
# differential_evolution step 827: f(x)= 85.18824793916035
# differential_evolution step 828: f(x)= 85.18824793916035
# differential_evolution step 829: f(x)= 85.18824793916035
# differential_evolution step 830: f(x)= 85.18824793916035
# differential_evolution step 831: f(x)= 85.18824793916035
# differential_evolution step 832: f(x)= 85.18824793916035
# differential_evolution step 833: f(x)= 85.18824793916035
# differential_evolution step 834: f(x)= 85.18740643603628
# differential_evolution step 835: f(x)= 85.18740643603628
# differential_evolution step 836: f(x)= 85.18560535144483
# differential_evolution step 837: f(x)= 85.18560535144483
# differential_evolution step 838: f(x)= 85.18560535144483
# differential_evolution step 839: f(x)= 85.18560535144483
# differential_evolution step 840: f(x)= 85.18560535144483
# differential_evolution step 841: f(x)= 85.18560535144483
# differential_evolution step 842: f(x)= 85.18560535144483
# differential_evolution step 843: f(x)= 85.18560535144483
# differential_evolution step 844: f(x)= 85.18560535144483
# differential_evolution step 845: f(x)= 85.18560535144483
# differential_evolution step 846: f(x)= 85.18560535144483
# differential_evolution step 847: f(x)= 85.18560535144483
# differential_evolution step 848: f(x)= 85.18560535144483
# differential_evolution step 849: f(x)= 85.18560535144483
# differential_evolution step 850: f(x)= 85.18560535144483
# differential_evolution step 851: f(x)= 85.18560535144483
# differential_evolution step 852: f(x)= 85.18560535144483
# differential_evolution step 853: f(x)= 85.18560535144483
# differential_evolution step 854: f(x)= 85.18503180361998
# differential_evolution step 855: f(x)= 85.18503180361998
# differential_evolution step 856: f(x)= 85.18503180361998
# differential_evolution step 857: f(x)= 85.18503180361998
# differential_evolution step 858: f(x)= 85.18503180361998
# differential_evolution step 859: f(x)= 85.18503180361998
# differential_evolution step 860: f(x)= 85.18503180361998
# differential_evolution step 861: f(x)= 85.18503180361998
# differential_evolution step 862: f(x)= 85.18503180361998
# differential_evolution step 863: f(x)= 85.18503180361998
# differential_evolution step 864: f(x)= 85.18503180361998
# differential_evolution step 865: f(x)= 85.18503180361998
# differential_evolution step 866: f(x)= 85.18503180361998
# differential_evolution step 867: f(x)= 85.18337237140145
# differential_evolution step 868: f(x)= 85.18337237140145
# differential_evolution step 869: f(x)= 85.18337237140145
# differential_evolution step 870: f(x)= 85.18036451445606
# differential_evolution step 871: f(x)= 85.18036451445606
# differential_evolution step 872: f(x)= 85.18036451445606
# differential_evolution step 873: f(x)= 85.18036451445606
# differential_evolution step 874: f(x)= 85.18036451445606
# differential_evolution step 875: f(x)= 85.18036451445606
# differential_evolution step 876: f(x)= 85.18036451445606
# differential_evolution step 877: f(x)= 85.18036451445606
# differential_evolution step 878: f(x)= 85.18036451445606
# differential_evolution step 879: f(x)= 85.18036451445606
# differential_evolution step 880: f(x)= 85.18036451445606
# differential_evolution step 881: f(x)= 85.18036451445606
# differential_evolution step 882: f(x)= 85.18036451445606
# differential_evolution step 883: f(x)= 85.18036451445606
# differential_evolution step 884: f(x)= 85.18036451445606
# differential_evolution step 885: f(x)= 85.18036451445606
# differential_evolution step 886: f(x)= 85.18036451445606
# differential_evolution step 887: f(x)= 85.18036451445606
# differential_evolution step 888: f(x)= 85.18036451445606
# differential_evolution step 889: f(x)= 85.18036451445606
# differential_evolution step 890: f(x)= 85.18036451445606
# differential_evolution step 891: f(x)= 85.18036451445606
# differential_evolution step 892: f(x)= 85.17975379342258
# differential_evolution step 893: f(x)= 85.17975379342258
# differential_evolution step 894: f(x)= 85.17975379342258
# differential_evolution step 895: f(x)= 85.17975379342258
# differential_evolution step 896: f(x)= 85.17975379342258
# differential_evolution step 897: f(x)= 85.17975379342258
# differential_evolution step 898: f(x)= 85.17975379342258
# differential_evolution step 899: f(x)= 85.17975379342258
# differential_evolution step 900: f(x)= 85.17881279298841
# differential_evolution step 901: f(x)= 85.17881279298841
# differential_evolution step 902: f(x)= 85.17881279298841
# differential_evolution step 903: f(x)= 85.17881279298841
# differential_evolution step 904: f(x)= 85.17881279298841
# differential_evolution step 905: f(x)= 85.17881279298841
# differential_evolution step 906: f(x)= 85.17881279298841
# differential_evolution step 907: f(x)= 85.17752240207128
# differential_evolution step 908: f(x)= 85.1758891548544
# differential_evolution step 909: f(x)= 85.1758891548544
# differential_evolution step 910: f(x)= 85.1758891548544
# differential_evolution step 911: f(x)= 85.1758891548544
# differential_evolution step 912: f(x)= 85.1758891548544
# differential_evolution step 913: f(x)= 85.1758891548544
# differential_evolution step 914: f(x)= 85.1758891548544
# differential_evolution step 915: f(x)= 85.1758891548544
# differential_evolution step 916: f(x)= 85.17570827725751
# differential_evolution step 917: f(x)= 85.17570827725751
# differential_evolution step 918: f(x)= 85.17570827725751
# differential_evolution step 919: f(x)= 85.17570827725751
# differential_evolution step 920: f(x)= 85.17570827725751
# differential_evolution step 921: f(x)= 85.17570827725751
# differential_evolution step 922: f(x)= 85.17570827725751
# differential_evolution step 923: f(x)= 85.17570827725751
# differential_evolution step 924: f(x)= 85.17570827725751
# differential_evolution step 925: f(x)= 85.17570827725751
# differential_evolution step 926: f(x)= 85.17570827725751
# differential_evolution step 927: f(x)= 85.17570827725751
# differential_evolution step 928: f(x)= 85.17570827725751
# differential_evolution step 929: f(x)= 85.17570827725751
# differential_evolution step 930: f(x)= 85.17570827725751
# differential_evolution step 931: f(x)= 85.17570827725751
# differential_evolution step 932: f(x)= 85.17444928132728
# differential_evolution step 933: f(x)= 85.17444928132728
# differential_evolution step 934: f(x)= 85.17444928132728
# differential_evolution step 935: f(x)= 85.17430631084453
# differential_evolution step 936: f(x)= 85.17430631084453
# differential_evolution step 937: f(x)= 85.17430631084453
# differential_evolution step 938: f(x)= 85.17423969492495
# differential_evolution step 939: f(x)= 85.17423969492495
# differential_evolution step 940: f(x)= 85.17423969492495
# differential_evolution step 941: f(x)= 85.17423969492495
# differential_evolution step 942: f(x)= 85.17423969492495
# differential_evolution step 943: f(x)= 85.17423969492495
# differential_evolution step 944: f(x)= 85.17423969492495
# differential_evolution step 945: f(x)= 85.17423969492495
# differential_evolution step 946: f(x)= 85.17423969492495
# differential_evolution step 947: f(x)= 85.17423969492495
# differential_evolution step 948: f(x)= 85.17423969492495
# differential_evolution step 949: f(x)= 85.17423969492495
# differential_evolution step 950: f(x)= 85.17423969492495
# differential_evolution step 951: f(x)= 85.17387259321237
# differential_evolution step 952: f(x)= 85.17387259321237
# differential_evolution step 953: f(x)= 85.17387259321237
# differential_evolution step 954: f(x)= 85.17387259321237
# differential_evolution step 955: f(x)= 85.17387259321237
# differential_evolution step 956: f(x)= 85.17387259321237
# differential_evolution step 957: f(x)= 85.17387259321237
# differential_evolution step 958: f(x)= 85.17387259321237
# differential_evolution step 959: f(x)= 85.17387259321237
# differential_evolution step 960: f(x)= 85.17387259321237
# differential_evolution step 961: f(x)= 85.17387259321237
# differential_evolution step 962: f(x)= 85.17387259321237
# differential_evolution step 963: f(x)= 85.17387259321237
# differential_evolution step 964: f(x)= 85.17387259321237
# differential_evolution step 965: f(x)= 85.17387259321237
# differential_evolution step 966: f(x)= 85.17387259321237
# differential_evolution step 967: f(x)= 85.17387259321237
# differential_evolution step 968: f(x)= 85.17387259321237
# differential_evolution step 969: f(x)= 85.17387259321237
# differential_evolution step 970: f(x)= 85.17348655713629
# differential_evolution step 971: f(x)= 85.17348655713629
# differential_evolution step 972: f(x)= 85.17348655713629
# differential_evolution step 973: f(x)= 85.17348655713629
# differential_evolution step 974: f(x)= 85.17348655713629
# differential_evolution step 975: f(x)= 85.17348655713629
# differential_evolution step 976: f(x)= 85.17348655713629
# differential_evolution step 977: f(x)= 85.17348655713629
# differential_evolution step 978: f(x)= 85.17348655713629
# differential_evolution step 979: f(x)= 85.17348655713629
# differential_evolution step 980: f(x)= 85.17348655713629
# differential_evolution step 981: f(x)= 85.17348655713629
# differential_evolution step 982: f(x)= 85.17348655713629
# differential_evolution step 983: f(x)= 85.17348655713629
# differential_evolution step 984: f(x)= 85.17348655713629
# differential_evolution step 985: f(x)= 85.17348655713629
# differential_evolution step 986: f(x)= 85.17348655713629
# differential_evolution step 987: f(x)= 85.17348655713629
# differential_evolution step 988: f(x)= 85.17348655713629
# differential_evolution step 989: f(x)= 85.17348655713629
# differential_evolution step 990: f(x)= 85.17348655713629
# differential_evolution step 991: f(x)= 85.17348655713629
# differential_evolution step 992: f(x)= 85.17348655713629
# differential_evolution step 993: f(x)= 85.17348655713629
# differential_evolution step 994: f(x)= 85.17348655713629
# differential_evolution step 995: f(x)= 85.17332475626509
# differential_evolution step 996: f(x)= 85.17332475626509
# differential_evolution step 997: f(x)= 85.17332475626509
# differential_evolution step 998: f(x)= 85.17332475626509
# differential_evolution step 999: f(x)= 85.17332475626509
# differential_evolution step 1000: f(x)= 85.17332475626509
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.5647, r_e=11.4670, n=1.0690, x_0=45.0000
# Sérsic 2: I_e=17.8520, r_e=1.8728, n=0.5445, x_0=51.4781
# Sérsic 3: I_e=17.4695, r_e=5.1607, n=0.8040, x_0=60.7109
# Sérsic 4: I_e=0.3802, r_e=46.4447, n=0.1102, x_0=36.9606
# Chi quadro minimo: 85.17093754614825
# False

# %%
plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')

# %%
bounds = [
    (0, 10),
    (0, 10),
    (0.1, 10),
    (44, 46),

    (0, 1),
    (20, 40),
    (0.1, 10),
    (50, 53),

    (0, 20),
    (0, 10),
    (0.1, 10),
    (59, 61), 

    (0, 10),
    (0, 5),
    (0.1, 10),
    (34, 37)
]
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA) #, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA_2, dof_HA_2, chi2_HA_2 = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16712\2569162179.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16712\2569162179.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=4.5037, r_e=9.8083, n=0.7544, x_0=47.9275
# Sérsic 2: I_e=22.1998, r_e=1.3163, n=0.3046, x_0=51.6341
# Sérsic 3: I_e=13.7658, r_e=5.5748, n=0.9577, x_0=60.8788
# Sérsic 4: I_e=0.3581, r_e=35.2799, n=0.8495, x_0=45.7615
# [ 1.24688903  1.19684409  0.12666374  2.49930044 18.43174374  0.42326535
#   0.75767887  0.12548873  1.1434273   0.19706277  0.05100925  0.17976099
#   0.11522124  5.52657564  1.21551613  1.02064759]
# 3.0421335135912364

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')

# %%
from scipy.stats import f
chi2_1 = chi2_HA_1
chi2_2 =  chi2_HA_2
dof_1 = dof_HA_1
dof_2 = dof_HA_1
# F-statistic
num = (chi2_1 - chi2_2) / (dof_1 - dof_2)
den = chi2_2 / dof_2
F = num / den
# p-value 
p_value = 1 - f.cdf(F, dof_1 - dof_2, dof_2)
print("F =", F)
print("p-value =", p_value)
# Out:
# F = inf
# p-value = nan
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16712\2516229832.py:7: RuntimeWarning: divide by zero encountered in scalar divide
#   num = (chi2_1 - chi2_2) / (dof_1 - dof_2)

# %%
num
# Out:
# inf
