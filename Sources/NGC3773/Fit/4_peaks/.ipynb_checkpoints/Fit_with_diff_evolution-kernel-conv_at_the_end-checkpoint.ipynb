# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32

# %%
image_cut = image[70:170, 0:1890]
image_error_cut = image_error[70:170, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.00328
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/PSF/Real_seeing_NGC3773.txt")
sigmas = seeing / 2.35
n_component = 3
print(sigmas)
# Out:
# [1.01016511 1.12309039 1.00840577 0.99664427 1.1197505  1.01319149]

# %%
l_HA
# Out:
# 6584.52664

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[70:170, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/NGC-3773_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 28)*(y < 38)
mask_wv = wv > 4450.5
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3773/Propag_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) #+
        #sersic_1d(x_hr, *params[12:16]) #+
        #sersic_1d(x_hr, *params[16:20])+ 
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 100)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 20),
    (0, 50),
    (0.1, 10),
    (43, 45),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (48, 53),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (57, 62)
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 5436.297071737934
# differential_evolution step 2: f(x)= 5436.297071737934
# differential_evolution step 3: f(x)= 5436.297071737934
# differential_evolution step 4: f(x)= 5436.297071737934
# differential_evolution step 5: f(x)= 2020.3552176036173
# differential_evolution step 6: f(x)= 2020.3552176036173
# differential_evolution step 7: f(x)= 2020.3552176036173
# differential_evolution step 8: f(x)= 2020.3552176036173
# differential_evolution step 9: f(x)= 2020.3552176036173
# differential_evolution step 10: f(x)= 2020.3552176036173
# differential_evolution step 11: f(x)= 2020.3552176036173
# differential_evolution step 12: f(x)= 2020.3552176036173
# differential_evolution step 13: f(x)= 1751.6701190994388
# differential_evolution step 14: f(x)= 1721.309326909147
# differential_evolution step 15: f(x)= 1721.309326909147
# differential_evolution step 16: f(x)= 1721.309326909147
# differential_evolution step 17: f(x)= 1560.8277713957903
# differential_evolution step 18: f(x)= 1560.8277713957903
# differential_evolution step 19: f(x)= 1511.393490841594
# differential_evolution step 20: f(x)= 1321.896452907467
# differential_evolution step 21: f(x)= 1321.896452907467
# differential_evolution step 22: f(x)= 1321.896452907467
# differential_evolution step 23: f(x)= 1321.896452907467
# differential_evolution step 24: f(x)= 1321.896452907467
# differential_evolution step 25: f(x)= 1321.896452907467
# differential_evolution step 26: f(x)= 1321.896452907467
# differential_evolution step 27: f(x)= 1296.411395115692
# differential_evolution step 28: f(x)= 1296.411395115692
# differential_evolution step 29: f(x)= 1084.796560609366
# differential_evolution step 30: f(x)= 959.9701862346342
# differential_evolution step 31: f(x)= 959.9701862346342
# differential_evolution step 32: f(x)= 959.9701862346342
# differential_evolution step 33: f(x)= 959.9701862346342
# differential_evolution step 34: f(x)= 735.6459197289414
# differential_evolution step 35: f(x)= 735.6459197289414
# differential_evolution step 36: f(x)= 655.6593674296896
# differential_evolution step 37: f(x)= 655.6593674296896
# differential_evolution step 38: f(x)= 655.6593674296896
# differential_evolution step 39: f(x)= 655.6593674296896
# differential_evolution step 40: f(x)= 655.6593674296896
# differential_evolution step 41: f(x)= 575.6714834388571
# differential_evolution step 42: f(x)= 575.6714834388571
# differential_evolution step 43: f(x)= 575.6714834388571
# differential_evolution step 44: f(x)= 547.5591002186496
# differential_evolution step 45: f(x)= 547.5591002186496
# differential_evolution step 46: f(x)= 547.5591002186496
# differential_evolution step 47: f(x)= 547.5591002186496
# differential_evolution step 48: f(x)= 547.5591002186496
# differential_evolution step 49: f(x)= 547.5591002186496
# differential_evolution step 50: f(x)= 448.87138228437914
# differential_evolution step 51: f(x)= 448.87138228437914
# differential_evolution step 52: f(x)= 448.87138228437914
# differential_evolution step 53: f(x)= 448.87138228437914
# differential_evolution step 54: f(x)= 448.87138228437914
# differential_evolution step 55: f(x)= 448.87138228437914
# differential_evolution step 56: f(x)= 420.7381627331662
# differential_evolution step 57: f(x)= 420.7381627331662
# differential_evolution step 58: f(x)= 420.7381627331662
# differential_evolution step 59: f(x)= 420.7381627331662
# differential_evolution step 60: f(x)= 420.7381627331662
# differential_evolution step 61: f(x)= 420.7381627331662
# differential_evolution step 62: f(x)= 394.94798007282145
# differential_evolution step 63: f(x)= 394.94798007282145
# differential_evolution step 64: f(x)= 394.94798007282145
# differential_evolution step 65: f(x)= 391.5734054881097
# differential_evolution step 66: f(x)= 391.5734054881097
# differential_evolution step 67: f(x)= 391.5734054881097
# differential_evolution step 68: f(x)= 391.5734054881097
# differential_evolution step 69: f(x)= 391.5734054881097
# differential_evolution step 70: f(x)= 391.5734054881097
# differential_evolution step 71: f(x)= 391.5734054881097
# differential_evolution step 72: f(x)= 331.8592913773769
# differential_evolution step 73: f(x)= 331.8592913773769
# differential_evolution step 74: f(x)= 331.8592913773769
# differential_evolution step 75: f(x)= 331.3438843047938
# differential_evolution step 76: f(x)= 313.8882688983717
# differential_evolution step 77: f(x)= 270.92552589377345
# differential_evolution step 78: f(x)= 270.92552589377345
# differential_evolution step 79: f(x)= 270.92552589377345
# differential_evolution step 80: f(x)= 270.92552589377345
# differential_evolution step 81: f(x)= 270.92552589377345
# differential_evolution step 82: f(x)= 270.92552589377345
# differential_evolution step 83: f(x)= 257.7371630059901
# differential_evolution step 84: f(x)= 257.7371630059901
# differential_evolution step 85: f(x)= 256.6485711007437
# differential_evolution step 86: f(x)= 256.6485711007437
# differential_evolution step 87: f(x)= 256.6485711007437
# differential_evolution step 88: f(x)= 244.13034586564473
# differential_evolution step 89: f(x)= 210.3649871566007
# differential_evolution step 90: f(x)= 200.1005332199938
# differential_evolution step 91: f(x)= 200.1005332199938
# differential_evolution step 92: f(x)= 188.47087370871574
# differential_evolution step 93: f(x)= 188.47087370871574
# differential_evolution step 94: f(x)= 188.47087370871574
# differential_evolution step 95: f(x)= 188.47087370871574
# differential_evolution step 96: f(x)= 188.47087370871574
# differential_evolution step 97: f(x)= 173.44297496763255
# differential_evolution step 98: f(x)= 173.44297496763255
# differential_evolution step 99: f(x)= 168.36503234126016
# differential_evolution step 100: f(x)= 168.36503234126016
# differential_evolution step 101: f(x)= 168.36503234126016
# differential_evolution step 102: f(x)= 168.36503234126016
# differential_evolution step 103: f(x)= 168.36503234126016
# differential_evolution step 104: f(x)= 168.36503234126016
# differential_evolution step 105: f(x)= 168.36503234126016
# differential_evolution step 106: f(x)= 160.98974502943054
# differential_evolution step 107: f(x)= 160.98974502943054
# differential_evolution step 108: f(x)= 160.98974502943054
# differential_evolution step 109: f(x)= 160.98974502943054
# differential_evolution step 110: f(x)= 160.98974502943054
# differential_evolution step 111: f(x)= 160.98974502943054
# differential_evolution step 112: f(x)= 160.98974502943054
# differential_evolution step 113: f(x)= 160.98974502943054
# differential_evolution step 114: f(x)= 160.98974502943054
# differential_evolution step 115: f(x)= 160.98974502943054
# differential_evolution step 116: f(x)= 160.98974502943054
# differential_evolution step 117: f(x)= 160.98974502943054
# differential_evolution step 118: f(x)= 160.98974502943054
# differential_evolution step 119: f(x)= 160.98974502943054
# differential_evolution step 120: f(x)= 160.98974502943054
# differential_evolution step 121: f(x)= 160.98974502943054
# differential_evolution step 122: f(x)= 160.98974502943054
# differential_evolution step 123: f(x)= 155.63542724190796
# differential_evolution step 124: f(x)= 155.63542724190796
# differential_evolution step 125: f(x)= 155.63542724190796
# differential_evolution step 126: f(x)= 148.44894456673887
# differential_evolution step 127: f(x)= 142.6004803763197
# differential_evolution step 128: f(x)= 142.6004803763197
# differential_evolution step 129: f(x)= 142.6004803763197
# differential_evolution step 130: f(x)= 142.6004803763197
# differential_evolution step 131: f(x)= 141.57835810456922
# differential_evolution step 132: f(x)= 141.57835810456922
# differential_evolution step 133: f(x)= 141.57835810456922
# differential_evolution step 134: f(x)= 141.57835810456922
# differential_evolution step 135: f(x)= 141.57835810456922
# differential_evolution step 136: f(x)= 141.57835810456922
# differential_evolution step 137: f(x)= 141.57835810456922
# differential_evolution step 138: f(x)= 141.57835810456922
# differential_evolution step 139: f(x)= 141.57835810456922
# differential_evolution step 140: f(x)= 141.57835810456922
# differential_evolution step 141: f(x)= 141.57835810456922
# differential_evolution step 142: f(x)= 137.4298192532925
# differential_evolution step 143: f(x)= 137.4298192532925
# differential_evolution step 144: f(x)= 137.4298192532925
# differential_evolution step 145: f(x)= 137.4298192532925
# differential_evolution step 146: f(x)= 137.4298192532925
# differential_evolution step 147: f(x)= 137.4298192532925
# differential_evolution step 148: f(x)= 137.4298192532925
# differential_evolution step 149: f(x)= 137.4298192532925
# differential_evolution step 150: f(x)= 137.4298192532925
# differential_evolution step 151: f(x)= 137.4298192532925
# differential_evolution step 152: f(x)= 137.4298192532925
# differential_evolution step 153: f(x)= 137.4298192532925
# differential_evolution step 154: f(x)= 137.4298192532925
# differential_evolution step 155: f(x)= 137.4298192532925
# differential_evolution step 156: f(x)= 137.4298192532925
# differential_evolution step 157: f(x)= 137.4298192532925
# differential_evolution step 158: f(x)= 137.4298192532925
# differential_evolution step 159: f(x)= 137.4298192532925
# differential_evolution step 160: f(x)= 137.4298192532925
# differential_evolution step 161: f(x)= 137.4298192532925
# differential_evolution step 162: f(x)= 137.4298192532925
# differential_evolution step 163: f(x)= 137.4298192532925
# differential_evolution step 164: f(x)= 137.4298192532925
# differential_evolution step 165: f(x)= 125.66496223005844
# differential_evolution step 166: f(x)= 125.66496223005844
# differential_evolution step 167: f(x)= 122.6827988823093
# differential_evolution step 168: f(x)= 122.6827988823093
# differential_evolution step 169: f(x)= 122.6827988823093
# differential_evolution step 170: f(x)= 122.6827988823093
# differential_evolution step 171: f(x)= 122.6827988823093
# differential_evolution step 172: f(x)= 122.6827988823093
# differential_evolution step 173: f(x)= 120.72038877470413
# differential_evolution step 174: f(x)= 120.72038877470413
# differential_evolution step 175: f(x)= 120.72038877470413
# differential_evolution step 176: f(x)= 120.72038877470413
# differential_evolution step 177: f(x)= 120.72038877470413
# differential_evolution step 178: f(x)= 120.72038877470413
# differential_evolution step 179: f(x)= 120.72038877470413
# differential_evolution step 180: f(x)= 120.72038877470413
# differential_evolution step 181: f(x)= 116.97636127861185
# differential_evolution step 182: f(x)= 116.97636127861185
# differential_evolution step 183: f(x)= 116.97636127861185
# differential_evolution step 184: f(x)= 116.97636127861185
# differential_evolution step 185: f(x)= 116.97636127861185
# differential_evolution step 186: f(x)= 116.97636127861185
# differential_evolution step 187: f(x)= 116.97636127861185
# differential_evolution step 188: f(x)= 116.97636127861185
# differential_evolution step 189: f(x)= 116.97636127861185
# differential_evolution step 190: f(x)= 116.97636127861185
# differential_evolution step 191: f(x)= 116.97636127861185
# differential_evolution step 192: f(x)= 116.97636127861185
# differential_evolution step 193: f(x)= 116.97636127861185
# differential_evolution step 194: f(x)= 116.97636127861185
# differential_evolution step 195: f(x)= 116.97636127861185
# differential_evolution step 196: f(x)= 116.97636127861185
# differential_evolution step 197: f(x)= 116.97636127861185
# differential_evolution step 198: f(x)= 116.97636127861185
# differential_evolution step 199: f(x)= 116.97636127861185
# differential_evolution step 200: f(x)= 116.97636127861185
# differential_evolution step 201: f(x)= 116.97636127861185
# differential_evolution step 202: f(x)= 116.97636127861185
# differential_evolution step 203: f(x)= 116.97636127861185
# differential_evolution step 204: f(x)= 116.97636127861185
# differential_evolution step 205: f(x)= 116.97636127861185
# differential_evolution step 206: f(x)= 116.97636127861185
# differential_evolution step 207: f(x)= 116.06132526550238
# differential_evolution step 208: f(x)= 116.06132526550238
# differential_evolution step 209: f(x)= 116.06132526550238
# differential_evolution step 210: f(x)= 116.06132526550238
# differential_evolution step 211: f(x)= 116.06132526550238
# differential_evolution step 212: f(x)= 116.06132526550238
# differential_evolution step 213: f(x)= 113.44385098612283
# differential_evolution step 214: f(x)= 113.44385098612283
# differential_evolution step 215: f(x)= 113.44385098612283
# differential_evolution step 216: f(x)= 113.44385098612283
# differential_evolution step 217: f(x)= 113.44385098612283
# differential_evolution step 218: f(x)= 113.44385098612283
# differential_evolution step 219: f(x)= 113.44385098612283
# differential_evolution step 220: f(x)= 112.11351155388395
# differential_evolution step 221: f(x)= 112.11351155388395
# differential_evolution step 222: f(x)= 112.11351155388395
# differential_evolution step 223: f(x)= 112.11351155388395
# differential_evolution step 224: f(x)= 111.6716431281837
# differential_evolution step 225: f(x)= 111.6716431281837
# differential_evolution step 226: f(x)= 111.6716431281837
# differential_evolution step 227: f(x)= 111.6716431281837
# differential_evolution step 228: f(x)= 111.6716431281837
# differential_evolution step 229: f(x)= 111.6716431281837
# differential_evolution step 230: f(x)= 111.6716431281837
# differential_evolution step 231: f(x)= 111.26720780240647
# differential_evolution step 232: f(x)= 111.26720780240647
# differential_evolution step 233: f(x)= 111.26720780240647
# differential_evolution step 234: f(x)= 109.91083949492331
# differential_evolution step 235: f(x)= 109.91083949492331
# differential_evolution step 236: f(x)= 109.91083949492331
# differential_evolution step 237: f(x)= 109.91083949492331
# differential_evolution step 238: f(x)= 109.91083949492331
# differential_evolution step 239: f(x)= 109.91083949492331
# differential_evolution step 240: f(x)= 109.91083949492331
# differential_evolution step 241: f(x)= 109.91083949492331
# differential_evolution step 242: f(x)= 109.91083949492331
# differential_evolution step 243: f(x)= 109.91083949492331
# differential_evolution step 244: f(x)= 109.91083949492331
# differential_evolution step 245: f(x)= 109.91083949492331
# differential_evolution step 246: f(x)= 109.91083949492331
# differential_evolution step 247: f(x)= 109.91083949492331
# differential_evolution step 248: f(x)= 109.91083949492331
# differential_evolution step 249: f(x)= 109.91083949492331
# differential_evolution step 250: f(x)= 109.91083949492331
# differential_evolution step 251: f(x)= 109.91083949492331
# differential_evolution step 252: f(x)= 109.91083949492331
# differential_evolution step 253: f(x)= 109.41852753752414
# differential_evolution step 254: f(x)= 109.41852753752414
# differential_evolution step 255: f(x)= 109.41852753752414
# differential_evolution step 256: f(x)= 109.41852753752414
# differential_evolution step 257: f(x)= 109.41852753752414
# differential_evolution step 258: f(x)= 109.41852753752414
# differential_evolution step 259: f(x)= 109.41852753752414
# differential_evolution step 260: f(x)= 109.41852753752414
# differential_evolution step 261: f(x)= 109.41852753752414
# differential_evolution step 262: f(x)= 108.80989162374098
# differential_evolution step 263: f(x)= 108.80989162374098
# differential_evolution step 264: f(x)= 108.80989162374098
# differential_evolution step 265: f(x)= 108.80989162374098
# differential_evolution step 266: f(x)= 108.80989162374098
# differential_evolution step 267: f(x)= 108.80989162374098
# differential_evolution step 268: f(x)= 108.80989162374098
# differential_evolution step 269: f(x)= 108.80989162374098
# differential_evolution step 270: f(x)= 108.80989162374098
# differential_evolution step 271: f(x)= 108.80989162374098
# differential_evolution step 272: f(x)= 108.80989162374098
# differential_evolution step 273: f(x)= 108.80989162374098
# differential_evolution step 274: f(x)= 108.80989162374098
# differential_evolution step 275: f(x)= 108.80989162374098
# differential_evolution step 276: f(x)= 108.80989162374098
# differential_evolution step 277: f(x)= 108.80989162374098
# differential_evolution step 278: f(x)= 108.80989162374098
# differential_evolution step 279: f(x)= 108.80989162374098
# differential_evolution step 280: f(x)= 108.73924162428753
# differential_evolution step 281: f(x)= 108.73924162428753
# differential_evolution step 282: f(x)= 108.42385379716454
# differential_evolution step 283: f(x)= 108.42385379716454
# differential_evolution step 284: f(x)= 108.42385379716454
# differential_evolution step 285: f(x)= 108.42102814315643
# differential_evolution step 286: f(x)= 108.42102814315643
# differential_evolution step 287: f(x)= 108.42102814315643
# differential_evolution step 288: f(x)= 108.42102814315643
# differential_evolution step 289: f(x)= 108.42102814315643
# differential_evolution step 290: f(x)= 108.42102814315643
# differential_evolution step 291: f(x)= 108.42102814315643
# differential_evolution step 292: f(x)= 108.42102814315643
# differential_evolution step 293: f(x)= 108.18947943486036
# differential_evolution step 294: f(x)= 108.18947943486036
# differential_evolution step 295: f(x)= 108.18947943486036
# differential_evolution step 296: f(x)= 108.18947943486036
# differential_evolution step 297: f(x)= 108.18947943486036
# differential_evolution step 298: f(x)= 108.18947943486036
# differential_evolution step 299: f(x)= 108.18947943486036
# differential_evolution step 300: f(x)= 108.18947943486036
# differential_evolution step 301: f(x)= 108.18947943486036
# differential_evolution step 302: f(x)= 108.18947943486036
# differential_evolution step 303: f(x)= 108.18947943486036
# differential_evolution step 304: f(x)= 108.18947943486036
# differential_evolution step 305: f(x)= 108.18947943486036
# differential_evolution step 306: f(x)= 108.18947943486036
# differential_evolution step 307: f(x)= 108.18947943486036
# differential_evolution step 308: f(x)= 108.18947943486036
# differential_evolution step 309: f(x)= 108.18947943486036
# differential_evolution step 310: f(x)= 108.18947943486036
# differential_evolution step 311: f(x)= 108.18947943486036
# differential_evolution step 312: f(x)= 108.18947943486036
# differential_evolution step 313: f(x)= 108.18947943486036
# differential_evolution step 314: f(x)= 108.18947943486036
# differential_evolution step 315: f(x)= 108.18947943486036
# differential_evolution step 316: f(x)= 108.18947943486036
# differential_evolution step 317: f(x)= 108.18947943486036
# differential_evolution step 318: f(x)= 108.18947943486036
# differential_evolution step 319: f(x)= 108.18947943486036
# differential_evolution step 320: f(x)= 108.18947943486036
# differential_evolution step 321: f(x)= 108.18947943486036
# differential_evolution step 322: f(x)= 108.18947943486036
# differential_evolution step 323: f(x)= 107.81605837605015
# differential_evolution step 324: f(x)= 107.81605837605015
# differential_evolution step 325: f(x)= 107.81605837605015
# differential_evolution step 326: f(x)= 107.81605837605015
# differential_evolution step 327: f(x)= 107.81605837605015
# differential_evolution step 328: f(x)= 107.81605837605015
# differential_evolution step 329: f(x)= 107.81605837605015
# differential_evolution step 330: f(x)= 107.81605837605015
# differential_evolution step 331: f(x)= 107.81605837605015
# differential_evolution step 332: f(x)= 107.55396333357552
# differential_evolution step 333: f(x)= 107.55396333357552
# differential_evolution step 334: f(x)= 107.55396333357552
# differential_evolution step 335: f(x)= 107.55396333357552
# differential_evolution step 336: f(x)= 107.55396333357552
# differential_evolution step 337: f(x)= 107.55396333357552
# differential_evolution step 338: f(x)= 107.55396333357552
# differential_evolution step 339: f(x)= 107.55396333357552
# differential_evolution step 340: f(x)= 107.55396333357552
# differential_evolution step 341: f(x)= 107.55396333357552
# differential_evolution step 342: f(x)= 107.55396333357552
# differential_evolution step 343: f(x)= 107.55396333357552
# differential_evolution step 344: f(x)= 107.55396333357552
# differential_evolution step 345: f(x)= 107.55396333357552
# differential_evolution step 346: f(x)= 107.55396333357552
# differential_evolution step 347: f(x)= 107.55396333357552
# differential_evolution step 348: f(x)= 107.55396333357552
# differential_evolution step 349: f(x)= 107.55396333357552
# differential_evolution step 350: f(x)= 107.55396333357552
# differential_evolution step 351: f(x)= 107.55396333357552
# differential_evolution step 352: f(x)= 107.55396333357552
# differential_evolution step 353: f(x)= 107.55396333357552
# differential_evolution step 354: f(x)= 107.55396333357552
# differential_evolution step 355: f(x)= 107.55396333357552
# differential_evolution step 356: f(x)= 107.55396333357552
# differential_evolution step 357: f(x)= 107.55396333357552
# differential_evolution step 358: f(x)= 107.55396333357552
# differential_evolution step 359: f(x)= 107.55396333357552
# differential_evolution step 360: f(x)= 107.55396333357552
# differential_evolution step 361: f(x)= 107.55396333357552
# differential_evolution step 362: f(x)= 107.55396333357552
# differential_evolution step 363: f(x)= 107.55396333357552
# differential_evolution step 364: f(x)= 107.55396333357552
# differential_evolution step 365: f(x)= 107.55396333357552
# differential_evolution step 366: f(x)= 107.55396333357552
# differential_evolution step 367: f(x)= 107.55396333357552
# differential_evolution step 368: f(x)= 107.55396333357552
# differential_evolution step 369: f(x)= 107.48286179074712
# differential_evolution step 370: f(x)= 107.48286179074712
# differential_evolution step 371: f(x)= 107.48286179074712
# differential_evolution step 372: f(x)= 107.48286179074712
# differential_evolution step 373: f(x)= 107.48286179074712
# differential_evolution step 374: f(x)= 107.48286179074712
# differential_evolution step 375: f(x)= 107.48286179074712
# differential_evolution step 376: f(x)= 107.48286179074712
# differential_evolution step 377: f(x)= 107.48286179074712
# differential_evolution step 378: f(x)= 107.48286179074712
# differential_evolution step 379: f(x)= 107.48286179074712
# differential_evolution step 380: f(x)= 107.48286179074712
# differential_evolution step 381: f(x)= 107.48286179074712
# differential_evolution step 382: f(x)= 107.48286179074712
# differential_evolution step 383: f(x)= 107.48286179074712
# differential_evolution step 384: f(x)= 107.48286179074712
# differential_evolution step 385: f(x)= 107.48286179074712
# differential_evolution step 386: f(x)= 107.48286179074712
# differential_evolution step 387: f(x)= 107.48286179074712
# differential_evolution step 388: f(x)= 107.48286179074712
# differential_evolution step 389: f(x)= 107.48286179074712
# differential_evolution step 390: f(x)= 107.48286179074712
# differential_evolution step 391: f(x)= 107.48286179074712
# differential_evolution step 392: f(x)= 107.48286179074712
# differential_evolution step 393: f(x)= 107.48286179074712
# differential_evolution step 394: f(x)= 107.48286179074712
# differential_evolution step 395: f(x)= 107.48286179074712
# differential_evolution step 396: f(x)= 107.48286179074712
# differential_evolution step 397: f(x)= 107.48286179074712
# differential_evolution step 398: f(x)= 107.48286179074712
# differential_evolution step 399: f(x)= 107.48286179074712
# differential_evolution step 400: f(x)= 107.48286179074712
# differential_evolution step 401: f(x)= 107.48286179074712
# differential_evolution step 402: f(x)= 107.48286179074712
# differential_evolution step 403: f(x)= 107.48286179074712
# differential_evolution step 404: f(x)= 107.48286179074712
# differential_evolution step 405: f(x)= 107.48286179074712
# differential_evolution step 406: f(x)= 107.48286179074712
# differential_evolution step 407: f(x)= 107.48286179074712
# differential_evolution step 408: f(x)= 107.48286179074712
# differential_evolution step 409: f(x)= 107.48286179074712
# differential_evolution step 410: f(x)= 107.44305523790138
# differential_evolution step 411: f(x)= 107.44305523790138
# differential_evolution step 412: f(x)= 107.44305523790138
# differential_evolution step 413: f(x)= 107.44305523790138
# differential_evolution step 414: f(x)= 107.44305523790138
# differential_evolution step 415: f(x)= 107.37583235141864
# differential_evolution step 416: f(x)= 107.37583235141864
# differential_evolution step 417: f(x)= 107.37583235141864
# differential_evolution step 418: f(x)= 107.37583235141864
# differential_evolution step 419: f(x)= 107.18236867795176
# differential_evolution step 420: f(x)= 107.18236867795176
# differential_evolution step 421: f(x)= 107.18236867795176
# differential_evolution step 422: f(x)= 107.11843841265245
# differential_evolution step 423: f(x)= 107.11843841265245
# differential_evolution step 424: f(x)= 107.11843841265245
# differential_evolution step 425: f(x)= 107.11843841265245
# differential_evolution step 426: f(x)= 107.07370530810688
# differential_evolution step 427: f(x)= 107.07370530810688
# differential_evolution step 428: f(x)= 106.89982313280464
# differential_evolution step 429: f(x)= 106.89982313280464
# differential_evolution step 430: f(x)= 106.89982313280464
# differential_evolution step 431: f(x)= 106.89982313280464
# differential_evolution step 432: f(x)= 106.89982313280464
# differential_evolution step 433: f(x)= 106.74912812815626
# differential_evolution step 434: f(x)= 106.74912812815626
# differential_evolution step 435: f(x)= 106.74912812815626
# differential_evolution step 436: f(x)= 106.74912812815626
# differential_evolution step 437: f(x)= 106.42876138747518
# differential_evolution step 438: f(x)= 106.42876138747518
# differential_evolution step 439: f(x)= 106.42876138747518
# differential_evolution step 440: f(x)= 106.37006835502531
# differential_evolution step 441: f(x)= 106.37006835502531
# differential_evolution step 442: f(x)= 106.37006835502531
# differential_evolution step 443: f(x)= 106.37006835502531
# differential_evolution step 444: f(x)= 106.37006835502531
# differential_evolution step 445: f(x)= 106.29740694215883
# differential_evolution step 446: f(x)= 106.29740694215883
# differential_evolution step 447: f(x)= 106.29740694215883
# differential_evolution step 448: f(x)= 106.29740694215883
# differential_evolution step 449: f(x)= 106.29740694215883
# differential_evolution step 450: f(x)= 106.29740694215883
# differential_evolution step 451: f(x)= 106.29740694215883
# differential_evolution step 452: f(x)= 106.29740694215883
# differential_evolution step 453: f(x)= 106.29740694215883
# differential_evolution step 454: f(x)= 106.29740694215883
# differential_evolution step 455: f(x)= 106.29740694215883
# differential_evolution step 456: f(x)= 106.29740694215883
# differential_evolution step 457: f(x)= 106.29740694215883
# differential_evolution step 458: f(x)= 106.29740694215883
# differential_evolution step 459: f(x)= 106.29740694215883
# differential_evolution step 460: f(x)= 106.29740694215883
# differential_evolution step 461: f(x)= 106.29740694215883
# differential_evolution step 462: f(x)= 106.25284217032849
# differential_evolution step 463: f(x)= 106.25284217032849
# differential_evolution step 464: f(x)= 106.25284217032849
# differential_evolution step 465: f(x)= 106.25284217032849
# differential_evolution step 466: f(x)= 106.25284217032849
# differential_evolution step 467: f(x)= 106.06017884892115
# differential_evolution step 468: f(x)= 106.06017884892115
# differential_evolution step 469: f(x)= 106.06017884892115
# differential_evolution step 470: f(x)= 106.06017884892115
# differential_evolution step 471: f(x)= 106.06017884892115
# differential_evolution step 472: f(x)= 106.01117968245127
# differential_evolution step 473: f(x)= 106.01117968245127
# differential_evolution step 474: f(x)= 106.01117968245127
# differential_evolution step 475: f(x)= 106.01117968245127
# differential_evolution step 476: f(x)= 106.01117968245127
# differential_evolution step 477: f(x)= 105.75602095301927
# differential_evolution step 478: f(x)= 105.75602095301927
# differential_evolution step 479: f(x)= 105.75602095301927
# differential_evolution step 480: f(x)= 105.75602095301927
# differential_evolution step 481: f(x)= 105.4075923871153
# differential_evolution step 482: f(x)= 105.4075923871153
# differential_evolution step 483: f(x)= 105.4075923871153
# differential_evolution step 484: f(x)= 105.4075923871153
# differential_evolution step 485: f(x)= 105.4075923871153
# differential_evolution step 486: f(x)= 105.38600506957165
# differential_evolution step 487: f(x)= 105.26593025979088
# differential_evolution step 488: f(x)= 105.26593025979088
# differential_evolution step 489: f(x)= 105.06762823474479
# differential_evolution step 490: f(x)= 105.06762823474479
# differential_evolution step 491: f(x)= 105.06762823474479
# differential_evolution step 492: f(x)= 105.06762823474479
# differential_evolution step 493: f(x)= 105.06762823474479
# differential_evolution step 494: f(x)= 105.06762823474479
# differential_evolution step 495: f(x)= 105.06762823474479
# differential_evolution step 496: f(x)= 105.06762823474479
# differential_evolution step 497: f(x)= 105.06762823474479
# differential_evolution step 498: f(x)= 105.06762823474479
# differential_evolution step 499: f(x)= 105.06762823474479
# differential_evolution step 500: f(x)= 104.82323089834864
# differential_evolution step 501: f(x)= 104.69366527600292
# differential_evolution step 502: f(x)= 104.69366527600292
# differential_evolution step 503: f(x)= 104.69366527600292
# differential_evolution step 504: f(x)= 104.50350358820509
# differential_evolution step 505: f(x)= 104.44645814211076
# differential_evolution step 506: f(x)= 104.44645814211076
# differential_evolution step 507: f(x)= 104.32050470119039
# differential_evolution step 508: f(x)= 104.20526671068747
# differential_evolution step 509: f(x)= 104.20526671068747
# differential_evolution step 510: f(x)= 104.20526671068747
# differential_evolution step 511: f(x)= 104.20526671068747
# differential_evolution step 512: f(x)= 104.20526671068747
# differential_evolution step 513: f(x)= 103.51164387757899
# differential_evolution step 514: f(x)= 103.16111268246058
# differential_evolution step 515: f(x)= 103.16111268246058
# differential_evolution step 516: f(x)= 103.16111268246058
# differential_evolution step 517: f(x)= 103.16111268246058
# differential_evolution step 518: f(x)= 103.16111268246058
# differential_evolution step 519: f(x)= 103.16111268246058
# differential_evolution step 520: f(x)= 103.16111268246058
# differential_evolution step 521: f(x)= 102.85718887055135
# differential_evolution step 522: f(x)= 102.85718887055135
# differential_evolution step 523: f(x)= 102.37439426533469
# differential_evolution step 524: f(x)= 102.37439426533469
# differential_evolution step 525: f(x)= 102.37439426533469
# differential_evolution step 526: f(x)= 102.37439426533469
# differential_evolution step 527: f(x)= 102.37439426533469
# differential_evolution step 528: f(x)= 102.37439426533469
# differential_evolution step 529: f(x)= 102.37439426533469
# differential_evolution step 530: f(x)= 102.37439426533469
# differential_evolution step 531: f(x)= 102.37439426533469
# differential_evolution step 532: f(x)= 102.37439426533469
# differential_evolution step 533: f(x)= 102.37439426533469
# differential_evolution step 534: f(x)= 102.37439426533469
# differential_evolution step 535: f(x)= 102.37439426533469
# differential_evolution step 536: f(x)= 102.37439426533469
# differential_evolution step 537: f(x)= 102.37439426533469
# differential_evolution step 538: f(x)= 102.37439426533469
# differential_evolution step 539: f(x)= 102.01450008001407
# differential_evolution step 540: f(x)= 102.01450008001407
# differential_evolution step 541: f(x)= 102.01450008001407
# differential_evolution step 542: f(x)= 102.01450008001407
# differential_evolution step 543: f(x)= 102.01450008001407
# differential_evolution step 544: f(x)= 102.01450008001407
# differential_evolution step 545: f(x)= 102.01450008001407
# differential_evolution step 546: f(x)= 101.61888499782957
# differential_evolution step 547: f(x)= 101.61888499782957
# differential_evolution step 548: f(x)= 101.61888499782957
# differential_evolution step 549: f(x)= 101.09924212613588
# differential_evolution step 550: f(x)= 100.96167427084302
# differential_evolution step 551: f(x)= 100.08576483067814
# differential_evolution step 552: f(x)= 99.81209434115951
# differential_evolution step 553: f(x)= 99.48648476250486
# differential_evolution step 554: f(x)= 99.48648476250486
# differential_evolution step 555: f(x)= 99.32743483616456
# differential_evolution step 556: f(x)= 99.32743483616456
# differential_evolution step 557: f(x)= 99.32743483616456
# differential_evolution step 558: f(x)= 99.32743483616456
# differential_evolution step 559: f(x)= 98.7672379858676
# differential_evolution step 560: f(x)= 98.7672379858676
# differential_evolution step 561: f(x)= 98.7672379858676
# differential_evolution step 562: f(x)= 98.7672379858676
# differential_evolution step 563: f(x)= 98.7672379858676
# differential_evolution step 564: f(x)= 98.7672379858676
# differential_evolution step 565: f(x)= 98.61461833946379
# differential_evolution step 566: f(x)= 98.61461833946379
# differential_evolution step 567: f(x)= 98.61461833946379
# differential_evolution step 568: f(x)= 98.48809253984221
# differential_evolution step 569: f(x)= 98.48809253984221
# differential_evolution step 570: f(x)= 98.48809253984221
# differential_evolution step 571: f(x)= 98.48809253984221
# differential_evolution step 572: f(x)= 98.48809253984221
# differential_evolution step 573: f(x)= 98.48809253984221
# differential_evolution step 574: f(x)= 98.48809253984221
# differential_evolution step 575: f(x)= 97.86005136474418
# differential_evolution step 576: f(x)= 96.75436853781838
# differential_evolution step 577: f(x)= 96.75436853781838
# differential_evolution step 578: f(x)= 96.75436853781838
# differential_evolution step 579: f(x)= 96.75436853781838
# differential_evolution step 580: f(x)= 96.75436853781838
# differential_evolution step 581: f(x)= 96.75436853781838
# differential_evolution step 582: f(x)= 96.01932279972193
# differential_evolution step 583: f(x)= 95.35641113596051
# differential_evolution step 584: f(x)= 95.18444109817618
# differential_evolution step 585: f(x)= 95.18444109817618
# differential_evolution step 586: f(x)= 94.51755542319601
# differential_evolution step 587: f(x)= 94.51755542319601
# differential_evolution step 588: f(x)= 94.51755542319601
# differential_evolution step 589: f(x)= 94.51755542319601
# differential_evolution step 590: f(x)= 94.51755542319601
# differential_evolution step 591: f(x)= 94.49431911267439
# differential_evolution step 592: f(x)= 94.49431911267439
# differential_evolution step 593: f(x)= 94.49431911267439
# differential_evolution step 594: f(x)= 94.49431911267439
# differential_evolution step 595: f(x)= 92.68359580235735
# differential_evolution step 596: f(x)= 92.68359580235735
# differential_evolution step 597: f(x)= 92.65967252996236
# differential_evolution step 598: f(x)= 92.65967252996236
# differential_evolution step 599: f(x)= 91.9454449295496
# differential_evolution step 600: f(x)= 91.9454449295496
# differential_evolution step 601: f(x)= 91.9454449295496
# differential_evolution step 602: f(x)= 91.9454449295496
# differential_evolution step 603: f(x)= 91.9454449295496
# differential_evolution step 604: f(x)= 91.25257378139786
# differential_evolution step 605: f(x)= 91.25257378139786
# differential_evolution step 606: f(x)= 91.25257378139786
# differential_evolution step 607: f(x)= 91.25257378139786
# differential_evolution step 608: f(x)= 91.25257378139786
# differential_evolution step 609: f(x)= 91.25257378139786
# differential_evolution step 610: f(x)= 90.94393560428743
# differential_evolution step 611: f(x)= 90.94393560428743
# differential_evolution step 612: f(x)= 89.59762767785934
# differential_evolution step 613: f(x)= 89.59762767785934
# differential_evolution step 614: f(x)= 89.59762767785934
# differential_evolution step 615: f(x)= 89.59762767785934
# differential_evolution step 616: f(x)= 89.59762767785934
# differential_evolution step 617: f(x)= 89.59762767785934
# differential_evolution step 618: f(x)= 89.59762767785934
# differential_evolution step 619: f(x)= 89.59762767785934
# differential_evolution step 620: f(x)= 89.59762767785934
# differential_evolution step 621: f(x)= 89.59762767785934
# differential_evolution step 622: f(x)= 89.59762767785934
# differential_evolution step 623: f(x)= 89.59762767785934
# differential_evolution step 624: f(x)= 89.59762767785934
# differential_evolution step 625: f(x)= 89.59762767785934
# differential_evolution step 626: f(x)= 89.38838772701806
# differential_evolution step 627: f(x)= 89.38838772701806
# differential_evolution step 628: f(x)= 89.26681174997924
# differential_evolution step 629: f(x)= 89.26681174997924
# differential_evolution step 630: f(x)= 88.87803735834042
# differential_evolution step 631: f(x)= 88.87803735834042
# differential_evolution step 632: f(x)= 88.87803735834042
# differential_evolution step 633: f(x)= 88.87803735834042
# differential_evolution step 634: f(x)= 88.87803735834042
# differential_evolution step 635: f(x)= 88.87803735834042
# differential_evolution step 636: f(x)= 88.87803735834042
# differential_evolution step 637: f(x)= 88.87803735834042
# differential_evolution step 638: f(x)= 88.87803735834042
# differential_evolution step 639: f(x)= 88.69479090934279
# differential_evolution step 640: f(x)= 88.69479090934279
# differential_evolution step 641: f(x)= 88.69479090934279
# differential_evolution step 642: f(x)= 88.69479090934279
# differential_evolution step 643: f(x)= 88.69479090934279
# differential_evolution step 644: f(x)= 88.03544538988768
# differential_evolution step 645: f(x)= 88.03544538988768
# differential_evolution step 646: f(x)= 88.03544538988768
# differential_evolution step 647: f(x)= 88.03544538988768
# differential_evolution step 648: f(x)= 88.03544538988768
# differential_evolution step 649: f(x)= 88.03544538988768
# differential_evolution step 650: f(x)= 88.03544538988768
# differential_evolution step 651: f(x)= 87.86352089549135
# differential_evolution step 652: f(x)= 87.54412536894367
# differential_evolution step 653: f(x)= 87.51171106805634
# differential_evolution step 654: f(x)= 87.51171106805634
# differential_evolution step 655: f(x)= 87.51171106805634
# differential_evolution step 656: f(x)= 87.51171106805634
# differential_evolution step 657: f(x)= 87.51171106805634
# differential_evolution step 658: f(x)= 87.51171106805634
# differential_evolution step 659: f(x)= 87.51171106805634
# differential_evolution step 660: f(x)= 87.51171106805634
# differential_evolution step 661: f(x)= 87.51171106805634
# differential_evolution step 662: f(x)= 87.51171106805634
# differential_evolution step 663: f(x)= 87.51171106805634
# differential_evolution step 664: f(x)= 87.51171106805634
# differential_evolution step 665: f(x)= 87.51171106805634
# differential_evolution step 666: f(x)= 87.51171106805634
# differential_evolution step 667: f(x)= 87.51171106805634
# differential_evolution step 668: f(x)= 87.51171106805634
# differential_evolution step 669: f(x)= 87.51171106805634
# differential_evolution step 670: f(x)= 87.51171106805634
# differential_evolution step 671: f(x)= 87.51171106805634
# differential_evolution step 672: f(x)= 87.51171106805634
# differential_evolution step 673: f(x)= 87.51171106805634
# differential_evolution step 674: f(x)= 87.51171106805634
# differential_evolution step 675: f(x)= 87.51171106805634
# differential_evolution step 676: f(x)= 87.51171106805634
# differential_evolution step 677: f(x)= 87.51171106805634
# differential_evolution step 678: f(x)= 87.40644154887595
# differential_evolution step 679: f(x)= 87.40644154887595
# differential_evolution step 680: f(x)= 87.40644154887595
# differential_evolution step 681: f(x)= 87.40644154887595
# differential_evolution step 682: f(x)= 87.40644154887595
# differential_evolution step 683: f(x)= 87.40644154887595
# differential_evolution step 684: f(x)= 87.34500468061648
# differential_evolution step 685: f(x)= 87.34500468061648
# differential_evolution step 686: f(x)= 87.34500468061648
# differential_evolution step 687: f(x)= 87.34500468061648
# differential_evolution step 688: f(x)= 87.34500468061648
# differential_evolution step 689: f(x)= 87.27121638677076
# differential_evolution step 690: f(x)= 87.27121638677076
# differential_evolution step 691: f(x)= 87.27121638677076
# differential_evolution step 692: f(x)= 87.27121638677076
# differential_evolution step 693: f(x)= 87.27121638677076
# differential_evolution step 694: f(x)= 87.27121638677076
# differential_evolution step 695: f(x)= 87.22722052075969
# differential_evolution step 696: f(x)= 87.22722052075969
# differential_evolution step 697: f(x)= 87.22722052075969
# differential_evolution step 698: f(x)= 87.22722052075969
# differential_evolution step 699: f(x)= 87.22722052075969
# differential_evolution step 700: f(x)= 87.22722052075969
# differential_evolution step 701: f(x)= 87.22722052075969
# differential_evolution step 702: f(x)= 87.22722052075969
# differential_evolution step 703: f(x)= 87.22722052075969
# differential_evolution step 704: f(x)= 87.22722052075969
# differential_evolution step 705: f(x)= 87.22722052075969
# differential_evolution step 706: f(x)= 87.22722052075969
# differential_evolution step 707: f(x)= 87.22722052075969
# differential_evolution step 708: f(x)= 87.22722052075969
# differential_evolution step 709: f(x)= 87.22722052075969
# differential_evolution step 710: f(x)= 87.21452170679363
# differential_evolution step 711: f(x)= 87.21452170679363
# differential_evolution step 712: f(x)= 87.21452170679363
# differential_evolution step 713: f(x)= 87.21452170679363
# differential_evolution step 714: f(x)= 87.21452170679363
# differential_evolution step 715: f(x)= 87.21452170679363
# differential_evolution step 716: f(x)= 87.21452170679363
# differential_evolution step 717: f(x)= 87.21452170679363
# differential_evolution step 718: f(x)= 87.21452170679363
# differential_evolution step 719: f(x)= 87.21452170679363
# differential_evolution step 720: f(x)= 87.17589910700917
# differential_evolution step 721: f(x)= 87.17589910700917
# differential_evolution step 722: f(x)= 87.17589910700917
# differential_evolution step 723: f(x)= 87.17589910700917
# differential_evolution step 724: f(x)= 87.17589910700917
# differential_evolution step 725: f(x)= 87.17589910700917
# differential_evolution step 726: f(x)= 87.17589910700917
# differential_evolution step 727: f(x)= 87.17589910700917
# differential_evolution step 728: f(x)= 87.17589910700917
# differential_evolution step 729: f(x)= 87.17589910700917
# differential_evolution step 730: f(x)= 87.16576944938492
# differential_evolution step 731: f(x)= 87.16576944938492
# differential_evolution step 732: f(x)= 87.16576944938492
# differential_evolution step 733: f(x)= 87.13623095590965
# differential_evolution step 734: f(x)= 87.13623095590965
# differential_evolution step 735: f(x)= 87.13623095590965
# differential_evolution step 736: f(x)= 87.13623095590965
# differential_evolution step 737: f(x)= 87.13623095590965
# differential_evolution step 738: f(x)= 87.13623095590965
# differential_evolution step 739: f(x)= 87.13623095590965
# differential_evolution step 740: f(x)= 87.1041251391928
# differential_evolution step 741: f(x)= 87.1041251391928
# differential_evolution step 742: f(x)= 87.1041251391928
# differential_evolution step 743: f(x)= 87.1041251391928
# differential_evolution step 744: f(x)= 87.1041251391928
# differential_evolution step 745: f(x)= 87.1041251391928
# differential_evolution step 746: f(x)= 87.1041251391928
# differential_evolution step 747: f(x)= 87.1041251391928
# differential_evolution step 748: f(x)= 87.1041251391928
# differential_evolution step 749: f(x)= 87.1041251391928
# differential_evolution step 750: f(x)= 87.07988140665432
# differential_evolution step 751: f(x)= 87.07988140665432
# differential_evolution step 752: f(x)= 87.07988140665432
# differential_evolution step 753: f(x)= 87.07988140665432
# differential_evolution step 754: f(x)= 87.07988140665432
# differential_evolution step 755: f(x)= 87.07988140665432
# differential_evolution step 756: f(x)= 87.07988140665432
# differential_evolution step 757: f(x)= 87.07988140665432
# differential_evolution step 758: f(x)= 87.07988140665432
# differential_evolution step 759: f(x)= 87.07988140665432
# differential_evolution step 760: f(x)= 87.07988140665432
# differential_evolution step 761: f(x)= 87.07988140665432
# differential_evolution step 762: f(x)= 87.07988140665432
# differential_evolution step 763: f(x)= 87.07988140665432
# differential_evolution step 764: f(x)= 87.07988140665432
# differential_evolution step 765: f(x)= 87.07988140665432
# differential_evolution step 766: f(x)= 87.07988140665432
# differential_evolution step 767: f(x)= 87.07988140665432
# differential_evolution step 768: f(x)= 87.07988140665432
# differential_evolution step 769: f(x)= 87.07988140665432
# differential_evolution step 770: f(x)= 87.07988140665432
# differential_evolution step 771: f(x)= 87.07988140665432
# differential_evolution step 772: f(x)= 87.07988140665432
# differential_evolution step 773: f(x)= 87.07988140665432
# differential_evolution step 774: f(x)= 87.07988140665432
# differential_evolution step 775: f(x)= 87.07988140665432
# differential_evolution step 776: f(x)= 87.07988140665432
# differential_evolution step 777: f(x)= 87.07988140665432
# differential_evolution step 778: f(x)= 87.07988140665432
# differential_evolution step 779: f(x)= 87.07988140665432
# differential_evolution step 780: f(x)= 87.07988140665432
# differential_evolution step 781: f(x)= 87.06871037638867
# differential_evolution step 782: f(x)= 87.06871037638867
# differential_evolution step 783: f(x)= 87.06871037638867
# differential_evolution step 784: f(x)= 87.06871037638867
# differential_evolution step 785: f(x)= 87.06871037638867
# differential_evolution step 786: f(x)= 87.06871037638867
# differential_evolution step 787: f(x)= 87.06871037638867
# differential_evolution step 788: f(x)= 87.06871037638867
# differential_evolution step 789: f(x)= 87.06871037638867
# differential_evolution step 790: f(x)= 87.05236316503935
# differential_evolution step 791: f(x)= 87.05236316503935
# differential_evolution step 792: f(x)= 87.05236316503935
# differential_evolution step 793: f(x)= 87.05236316503935
# differential_evolution step 794: f(x)= 87.05236316503935
# differential_evolution step 795: f(x)= 87.05236316503935
# differential_evolution step 796: f(x)= 87.05236316503935
# differential_evolution step 797: f(x)= 87.05064849415092
# differential_evolution step 798: f(x)= 87.05064849415092
# differential_evolution step 799: f(x)= 87.05064849415092
# differential_evolution step 800: f(x)= 87.05064849415092
# differential_evolution step 801: f(x)= 87.05064849415092
# differential_evolution step 802: f(x)= 87.05064849415092
# differential_evolution step 803: f(x)= 87.05064849415092
# differential_evolution step 804: f(x)= 87.05064849415092
# differential_evolution step 805: f(x)= 87.05064849415092
# differential_evolution step 806: f(x)= 87.05064849415092
# differential_evolution step 807: f(x)= 87.05064849415092
# differential_evolution step 808: f(x)= 87.05064849415092
# differential_evolution step 809: f(x)= 87.05064849415092
# differential_evolution step 810: f(x)= 87.04990122860988
# differential_evolution step 811: f(x)= 87.04990122860988
# differential_evolution step 812: f(x)= 87.04990122860988
# differential_evolution step 813: f(x)= 87.04990122860988
# differential_evolution step 814: f(x)= 87.04259670230596
# differential_evolution step 815: f(x)= 87.04259670230596
# differential_evolution step 816: f(x)= 87.04259670230596
# differential_evolution step 817: f(x)= 87.04259670230596
# differential_evolution step 818: f(x)= 87.04259670230596
# differential_evolution step 819: f(x)= 87.04259670230596
# differential_evolution step 820: f(x)= 87.04259670230596
# differential_evolution step 821: f(x)= 87.04081786910216
# differential_evolution step 822: f(x)= 87.04081786910216
# differential_evolution step 823: f(x)= 87.04081786910216
# differential_evolution step 824: f(x)= 87.04081786910216
# differential_evolution step 825: f(x)= 87.04081786910216
# differential_evolution step 826: f(x)= 87.04081786910216
# differential_evolution step 827: f(x)= 87.04081786910216
# differential_evolution step 828: f(x)= 87.04081786910216
# differential_evolution step 829: f(x)= 87.04081786910216
# differential_evolution step 830: f(x)= 87.04081786910216
# differential_evolution step 831: f(x)= 87.04081786910216
# differential_evolution step 832: f(x)= 87.04081786910216
# differential_evolution step 833: f(x)= 87.04081786910216
# differential_evolution step 834: f(x)= 87.04081786910216
# differential_evolution step 835: f(x)= 87.04081786910216
# differential_evolution step 836: f(x)= 87.04081786910216
# differential_evolution step 837: f(x)= 87.04010158674221
# differential_evolution step 838: f(x)= 87.04010158674221
# differential_evolution step 839: f(x)= 87.04010158674221
# differential_evolution step 840: f(x)= 87.04010158674221
# differential_evolution step 841: f(x)= 87.04010158674221
# differential_evolution step 842: f(x)= 87.04010158674221
# differential_evolution step 843: f(x)= 87.04010158674221
# differential_evolution step 844: f(x)= 87.03863005966286
# differential_evolution step 845: f(x)= 87.03863005966286
# differential_evolution step 846: f(x)= 87.03863005966286
# differential_evolution step 847: f(x)= 87.0366410347029
# differential_evolution step 848: f(x)= 87.0366410347029
# differential_evolution step 849: f(x)= 87.0366410347029
# differential_evolution step 850: f(x)= 87.0366410347029
# differential_evolution step 851: f(x)= 87.0366410347029
# differential_evolution step 852: f(x)= 87.03658414935616
# differential_evolution step 853: f(x)= 87.03658414935616
# differential_evolution step 854: f(x)= 87.03497587545537
# differential_evolution step 855: f(x)= 87.03497587545537
# differential_evolution step 856: f(x)= 87.03497587545537
# differential_evolution step 857: f(x)= 87.03497587545537
# differential_evolution step 858: f(x)= 87.03497587545537
# differential_evolution step 859: f(x)= 87.03497587545537
# differential_evolution step 860: f(x)= 87.03497587545537
# differential_evolution step 861: f(x)= 87.03497587545537
# differential_evolution step 862: f(x)= 87.03497587545537
# differential_evolution step 863: f(x)= 87.03497587545537
# differential_evolution step 864: f(x)= 87.03497587545537
# differential_evolution step 865: f(x)= 87.03461762871123
# differential_evolution step 866: f(x)= 87.03461762871123
# differential_evolution step 867: f(x)= 87.03461762871123
# differential_evolution step 868: f(x)= 87.03461762871123
# differential_evolution step 869: f(x)= 87.03461762871123
# differential_evolution step 870: f(x)= 87.03461762871123
# differential_evolution step 871: f(x)= 87.03461762871123
# differential_evolution step 872: f(x)= 87.03461762871123
# differential_evolution step 873: f(x)= 87.03461762871123
# differential_evolution step 874: f(x)= 87.03461762871123
# differential_evolution step 875: f(x)= 87.03461762871123
# differential_evolution step 876: f(x)= 87.03461762871123
# differential_evolution step 877: f(x)= 87.03461762871123
# differential_evolution step 878: f(x)= 87.03232283422132
# differential_evolution step 879: f(x)= 87.03232283422132
# differential_evolution step 880: f(x)= 87.03232283422132
# differential_evolution step 881: f(x)= 87.03232283422132
# differential_evolution step 882: f(x)= 87.03232283422132
# differential_evolution step 883: f(x)= 87.03232283422132
# differential_evolution step 884: f(x)= 87.03232283422132
# differential_evolution step 885: f(x)= 87.03232283422132
# differential_evolution step 886: f(x)= 87.03232283422132
# differential_evolution step 887: f(x)= 87.03232283422132
# differential_evolution step 888: f(x)= 87.03232283422132
# differential_evolution step 889: f(x)= 87.03232283422132
# differential_evolution step 890: f(x)= 87.03145267303951
# differential_evolution step 891: f(x)= 87.03145267303951
# differential_evolution step 892: f(x)= 87.03145267303951
# differential_evolution step 893: f(x)= 87.03145267303951
# differential_evolution step 894: f(x)= 87.03145267303951
# differential_evolution step 895: f(x)= 87.03145267303951
# differential_evolution step 896: f(x)= 87.03145267303951
# differential_evolution step 897: f(x)= 87.03145267303951
# differential_evolution step 898: f(x)= 87.03145267303951
# differential_evolution step 899: f(x)= 87.03145267303951
# differential_evolution step 900: f(x)= 87.03145267303951
# differential_evolution step 901: f(x)= 87.03145267303951
# differential_evolution step 902: f(x)= 87.03145267303951
# differential_evolution step 903: f(x)= 87.03145267303951
# differential_evolution step 904: f(x)= 87.03145267303951
# differential_evolution step 905: f(x)= 87.03145267303951
# differential_evolution step 906: f(x)= 87.03145267303951
# differential_evolution step 907: f(x)= 87.03145267303951
# differential_evolution step 908: f(x)= 87.03145267303951
# differential_evolution step 909: f(x)= 87.03145267303951
# differential_evolution step 910: f(x)= 87.03145267303951
# differential_evolution step 911: f(x)= 87.03145267303951
# differential_evolution step 912: f(x)= 87.03145267303951
# differential_evolution step 913: f(x)= 87.03145267303951
# differential_evolution step 914: f(x)= 87.03145267303951
# differential_evolution step 915: f(x)= 87.03145267303951
# differential_evolution step 916: f(x)= 87.03145267303951
# differential_evolution step 917: f(x)= 87.03145267303951
# differential_evolution step 918: f(x)= 87.0304217461334
# differential_evolution step 919: f(x)= 87.0304217461334
# differential_evolution step 920: f(x)= 87.0304217461334
# differential_evolution step 921: f(x)= 87.0304217461334
# differential_evolution step 922: f(x)= 87.0304217461334
# differential_evolution step 923: f(x)= 87.0304217461334
# differential_evolution step 924: f(x)= 87.0304217461334
# differential_evolution step 925: f(x)= 87.0304217461334
# differential_evolution step 926: f(x)= 87.0304217461334
# differential_evolution step 927: f(x)= 87.0304217461334
# differential_evolution step 928: f(x)= 87.0304217461334
# differential_evolution step 929: f(x)= 87.0304217461334
# differential_evolution step 930: f(x)= 87.0304217461334
# differential_evolution step 931: f(x)= 87.0304217461334
# differential_evolution step 932: f(x)= 87.0304217461334
# differential_evolution step 933: f(x)= 87.0304217461334
# differential_evolution step 934: f(x)= 87.0304217461334
# differential_evolution step 935: f(x)= 87.0304217461334
# differential_evolution step 936: f(x)= 87.0304217461334
# differential_evolution step 937: f(x)= 87.0304217461334
# differential_evolution step 938: f(x)= 87.02915355012749
# differential_evolution step 939: f(x)= 87.02915355012749
# differential_evolution step 940: f(x)= 87.02915355012749
# differential_evolution step 941: f(x)= 87.02915355012749
# differential_evolution step 942: f(x)= 87.02915355012749
# differential_evolution step 943: f(x)= 87.02915355012749
# differential_evolution step 944: f(x)= 87.02915355012749
# differential_evolution step 945: f(x)= 87.02915355012749
# differential_evolution step 946: f(x)= 87.02915355012749
# differential_evolution step 947: f(x)= 87.02915355012749
# differential_evolution step 948: f(x)= 87.02915355012749
# differential_evolution step 949: f(x)= 87.02915355012749
# differential_evolution step 950: f(x)= 87.02915355012749
# differential_evolution step 951: f(x)= 87.02915355012749
# differential_evolution step 952: f(x)= 87.02915355012749
# differential_evolution step 953: f(x)= 87.02915355012749
# differential_evolution step 954: f(x)= 87.02915355012749
# differential_evolution step 955: f(x)= 87.02915355012749
# differential_evolution step 956: f(x)= 87.02915355012749
# differential_evolution step 957: f(x)= 87.02915355012749
# differential_evolution step 958: f(x)= 87.02915355012749
# differential_evolution step 959: f(x)= 87.02915355012749
# differential_evolution step 960: f(x)= 87.02915355012749
# differential_evolution step 961: f(x)= 87.02915355012749
# differential_evolution step 962: f(x)= 87.02915355012749
# differential_evolution step 963: f(x)= 87.02915355012749
# differential_evolution step 964: f(x)= 87.02915355012749
# differential_evolution step 965: f(x)= 87.02915355012749
# differential_evolution step 966: f(x)= 87.02915355012749
# differential_evolution step 967: f(x)= 87.02915355012749
# differential_evolution step 968: f(x)= 87.02915355012749
# differential_evolution step 969: f(x)= 87.02915355012749
# differential_evolution step 970: f(x)= 87.02915355012749
# differential_evolution step 971: f(x)= 87.02915355012749
# differential_evolution step 972: f(x)= 87.02915355012749
# differential_evolution step 973: f(x)= 87.02915355012749
# differential_evolution step 974: f(x)= 87.02915355012749
# differential_evolution step 975: f(x)= 87.02915355012749
# differential_evolution step 976: f(x)= 87.02915355012749
# differential_evolution step 977: f(x)= 87.02915355012749
# differential_evolution step 978: f(x)= 87.02915355012749
# differential_evolution step 979: f(x)= 87.02915355012749
# differential_evolution step 980: f(x)= 87.02915355012749
# differential_evolution step 981: f(x)= 87.02915355012749
# differential_evolution step 982: f(x)= 87.02913680997834
# differential_evolution step 983: f(x)= 87.02913680997834
# differential_evolution step 984: f(x)= 87.02913680997834
# differential_evolution step 985: f(x)= 87.02886578620672
# differential_evolution step 986: f(x)= 87.02886578620672
# differential_evolution step 987: f(x)= 87.02886578620672
# differential_evolution step 988: f(x)= 87.02886578620672
# differential_evolution step 989: f(x)= 87.02886578620672
# differential_evolution step 990: f(x)= 87.02886578620672
# differential_evolution step 991: f(x)= 87.02886578620672
# differential_evolution step 992: f(x)= 87.02886578620672
# differential_evolution step 993: f(x)= 87.02877432937274
# differential_evolution step 994: f(x)= 87.02877432937274
# differential_evolution step 995: f(x)= 87.02877432937274
# differential_evolution step 996: f(x)= 87.02877432937274
# differential_evolution step 997: f(x)= 87.02877432937274
# differential_evolution step 998: f(x)= 87.02877432937274
# differential_evolution step 999: f(x)= 87.02872660861877
# differential_evolution step 1000: f(x)= 87.02872488996779
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.6939, r_e=17.5445, n=1.3357, x_0=45.0000
# Sérsic 2: I_e=18.0886, r_e=1.8793, n=0.5328, x_0=51.4595
# Sérsic 3: I_e=17.2646, r_e=5.1748, n=0.8092, x_0=60.7121
# Chi quadro minimo: 87.028528550499
# False

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=1.6939, r_e=17.5445, n=1.3357, x_0=45.0000
# Sérsic 2: I_e=18.0886, r_e=1.8793, n=0.5328, x_0=51.4595
# Sérsic 3: I_e=17.2646, r_e=5.1748, n=0.8092, x_0=60.7121
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(result.x)
# Out:
# [ 1.69393859 17.54448598  1.33568926 45.         18.08856236  1.87925008
#   0.53280202 51.45947083 17.26462186  5.17475972  0.80919576 60.71213619]

# %%
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.6123, r_e=18.4179, n=1.4963, x_0=46.5849
# Sérsic 2: I_e=25.7452, r_e=1.4628, n=0.2521, x_0=51.6200
# Sérsic 3: I_e=14.4430, r_e=5.5761, n=0.9465, x_0=60.7391
# [ 0.1804226   0.73784443  0.07133416  0.39582612 14.79107799  0.18515467
#   0.52857762  0.14307345  0.75704324  0.13307362  0.0500593   0.13057356]
# 5.76983943157452

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds = [
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-1.2, x_0_HA[0]+1.2),   # x_0: circa la posizione di Halpha

    (0, 0.1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-1.2, x_0_HA[1]+1.2),

    (0, 0.1),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-1.2, x_0_HA[2]+1.2),
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))

real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[0])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 407.3471280943255
# differential_evolution step 2: f(x)= 407.3471280943255
# differential_evolution step 3: f(x)= 400.98500503182
# differential_evolution step 4: f(x)= 281.3266265973825
# differential_evolution step 5: f(x)= 268.2127590561493
# differential_evolution step 6: f(x)= 254.90608496228114
# differential_evolution step 7: f(x)= 254.90608496228114
# differential_evolution step 8: f(x)= 254.90608496228114
# differential_evolution step 9: f(x)= 195.57860274998953
# differential_evolution step 10: f(x)= 191.94584591779537
# differential_evolution step 11: f(x)= 191.94584591779537
# differential_evolution step 12: f(x)= 154.7098785405722
# differential_evolution step 13: f(x)= 154.7098785405722
# differential_evolution step 14: f(x)= 154.7098785405722
# differential_evolution step 15: f(x)= 151.6154621339174
# differential_evolution step 16: f(x)= 149.54296364733182
# differential_evolution step 17: f(x)= 149.54296364733182
# differential_evolution step 18: f(x)= 135.46537961158464
# differential_evolution step 19: f(x)= 135.46537961158464
# differential_evolution step 20: f(x)= 135.46537961158464
# differential_evolution step 21: f(x)= 135.46537961158464
# differential_evolution step 22: f(x)= 129.45742272121913
# differential_evolution step 23: f(x)= 129.45742272121913
# differential_evolution step 24: f(x)= 129.45742272121913
# differential_evolution step 25: f(x)= 124.45389220811495
# differential_evolution step 26: f(x)= 124.45389220811495
# differential_evolution step 27: f(x)= 124.45389220811495
# differential_evolution step 28: f(x)= 124.45389220811495
# differential_evolution step 29: f(x)= 120.78264748045528
# differential_evolution step 30: f(x)= 120.78264748045528
# differential_evolution step 31: f(x)= 118.84262863682645
# differential_evolution step 32: f(x)= 118.84262863682645
# differential_evolution step 33: f(x)= 118.84262863682645
# differential_evolution step 34: f(x)= 116.50547130205858
# differential_evolution step 35: f(x)= 116.50547130205858
# differential_evolution step 36: f(x)= 116.50547130205858
# differential_evolution step 37: f(x)= 113.81498870497296
# differential_evolution step 38: f(x)= 113.51908114708495
# differential_evolution step 39: f(x)= 113.51908114708495
# differential_evolution step 40: f(x)= 113.51908114708495
# differential_evolution step 41: f(x)= 113.51908114708495
# differential_evolution step 42: f(x)= 113.51908114708495
# differential_evolution step 43: f(x)= 113.323023214742
# differential_evolution step 44: f(x)= 113.323023214742
# differential_evolution step 45: f(x)= 113.323023214742
# differential_evolution step 46: f(x)= 112.34939911393009
# differential_evolution step 47: f(x)= 112.34939911393009
# differential_evolution step 48: f(x)= 111.72436404267803
# differential_evolution step 49: f(x)= 111.72436404267803
# differential_evolution step 50: f(x)= 111.72436404267803
# differential_evolution step 51: f(x)= 111.12493589440321
# differential_evolution step 52: f(x)= 111.12493589440321
# differential_evolution step 53: f(x)= 111.12493589440321
# differential_evolution step 54: f(x)= 111.12493589440321
# differential_evolution step 55: f(x)= 111.12493589440321
# differential_evolution step 56: f(x)= 110.46429409472303
# differential_evolution step 57: f(x)= 110.46429409472303
# differential_evolution step 58: f(x)= 110.46429409472303
# differential_evolution step 59: f(x)= 110.46429409472303
# differential_evolution step 60: f(x)= 110.41563307158388
# differential_evolution step 61: f(x)= 110.41563307158388
# differential_evolution step 62: f(x)= 110.21843439712582
# differential_evolution step 63: f(x)= 110.10797663239737
# differential_evolution step 64: f(x)= 109.36169262947162
# differential_evolution step 65: f(x)= 109.07020551668418
# differential_evolution step 66: f(x)= 109.02920811498393
# differential_evolution step 67: f(x)= 109.02920811498393
# differential_evolution step 68: f(x)= 109.02920811498393
# differential_evolution step 69: f(x)= 109.02920811498393
# differential_evolution step 70: f(x)= 109.02920811498393
# differential_evolution step 71: f(x)= 109.02920811498393
# differential_evolution step 72: f(x)= 109.02920811498393
# differential_evolution step 73: f(x)= 109.02920811498393
# differential_evolution step 74: f(x)= 109.02920811498393
# differential_evolution step 75: f(x)= 109.02920811498393
# differential_evolution step 76: f(x)= 109.02920811498393
# differential_evolution step 77: f(x)= 109.02920811498393
# differential_evolution step 78: f(x)= 109.02920811498393
# differential_evolution step 79: f(x)= 109.02920811498393
# differential_evolution step 80: f(x)= 109.02920811498393
# differential_evolution step 81: f(x)= 109.02920811498393
# differential_evolution step 82: f(x)= 109.02754267378124
# differential_evolution step 83: f(x)= 109.02754267378124
# differential_evolution step 84: f(x)= 108.70796088106668
# differential_evolution step 85: f(x)= 108.70796088106668
# differential_evolution step 86: f(x)= 108.70796088106668
# differential_evolution step 87: f(x)= 108.70796088106668
# differential_evolution step 88: f(x)= 108.1670704841767
# differential_evolution step 89: f(x)= 108.03241513521988
# differential_evolution step 90: f(x)= 108.03241513521988
# differential_evolution step 91: f(x)= 108.03241513521988
# differential_evolution step 92: f(x)= 108.03241513521988
# differential_evolution step 93: f(x)= 108.03241513521988
# differential_evolution step 94: f(x)= 108.03241513521988
# differential_evolution step 95: f(x)= 108.03241513521988
# differential_evolution step 96: f(x)= 108.03241513521988
# differential_evolution step 97: f(x)= 108.03241513521988
# differential_evolution step 98: f(x)= 108.03241513521988
# differential_evolution step 99: f(x)= 108.03241513521988
# differential_evolution step 100: f(x)= 108.03241513521988
# differential_evolution step 101: f(x)= 108.03241513521988
# differential_evolution step 102: f(x)= 108.03241513521988
# differential_evolution step 103: f(x)= 108.03241513521988
# differential_evolution step 104: f(x)= 108.03241513521988
# differential_evolution step 105: f(x)= 108.03241513521988
# differential_evolution step 106: f(x)= 107.86788995725983
# differential_evolution step 107: f(x)= 107.86788995725983
# differential_evolution step 108: f(x)= 107.86788995725983
# differential_evolution step 109: f(x)= 107.63911238715289
# differential_evolution step 110: f(x)= 107.63911238715289
# differential_evolution step 111: f(x)= 107.63911238715289
# differential_evolution step 112: f(x)= 107.63911238715289
# differential_evolution step 113: f(x)= 107.63911238715289
# differential_evolution step 114: f(x)= 107.63911238715289
# differential_evolution step 115: f(x)= 107.63911238715289
# differential_evolution step 116: f(x)= 107.63911238715289
# differential_evolution step 117: f(x)= 107.63911238715289
# differential_evolution step 118: f(x)= 107.509498429006
# differential_evolution step 119: f(x)= 107.35559901610013
# differential_evolution step 120: f(x)= 107.35559901610013
# differential_evolution step 121: f(x)= 107.35559901610013
# differential_evolution step 122: f(x)= 107.35559901610013
# differential_evolution step 123: f(x)= 107.35559901610013
# differential_evolution step 124: f(x)= 107.35559901610013
# differential_evolution step 125: f(x)= 107.35559901610013
# differential_evolution step 126: f(x)= 107.35559901610013
# differential_evolution step 127: f(x)= 107.35559901610013
# differential_evolution step 128: f(x)= 107.35559901610013
# differential_evolution step 129: f(x)= 107.35559901610013
# differential_evolution step 130: f(x)= 107.35559901610013
# differential_evolution step 131: f(x)= 107.35559901610013
# differential_evolution step 132: f(x)= 107.35559901610013
# differential_evolution step 133: f(x)= 107.35559901610013
# differential_evolution step 134: f(x)= 107.35559901610013
# differential_evolution step 135: f(x)= 107.35559901610013
# differential_evolution step 136: f(x)= 107.35559901610013
# differential_evolution step 137: f(x)= 107.35559901610013
# differential_evolution step 138: f(x)= 107.35559901610013
# differential_evolution step 139: f(x)= 107.35559901610013
# differential_evolution step 140: f(x)= 107.35559901610013
# differential_evolution step 141: f(x)= 107.35559901610013
# differential_evolution step 142: f(x)= 107.35559901610013
# differential_evolution step 143: f(x)= 107.35559901610013
# differential_evolution step 144: f(x)= 107.35559901610013
# differential_evolution step 145: f(x)= 107.35559901610013
# differential_evolution step 146: f(x)= 107.35559901610013
# differential_evolution step 147: f(x)= 107.35559901610013
# differential_evolution step 148: f(x)= 107.35559901610013
# differential_evolution step 149: f(x)= 107.35559901610013
# differential_evolution step 150: f(x)= 107.35559901610013
# differential_evolution step 151: f(x)= 107.35559901610013
# differential_evolution step 152: f(x)= 107.29017600363696
# differential_evolution step 153: f(x)= 107.29017600363696
# differential_evolution step 154: f(x)= 107.29017600363696
# differential_evolution step 155: f(x)= 107.2508340806462
# differential_evolution step 156: f(x)= 107.2508340806462
# differential_evolution step 157: f(x)= 107.23452693946984
# differential_evolution step 158: f(x)= 107.23452693946984
# differential_evolution step 159: f(x)= 107.1939555183247
# differential_evolution step 160: f(x)= 107.1939555183247
# differential_evolution step 161: f(x)= 107.18921042040438
# differential_evolution step 162: f(x)= 107.18921042040438
# differential_evolution step 163: f(x)= 107.18921042040438
# differential_evolution step 164: f(x)= 107.18921042040438
# differential_evolution step 165: f(x)= 107.18921042040438
# differential_evolution step 166: f(x)= 107.18921042040438
# differential_evolution step 167: f(x)= 107.18921042040438
# differential_evolution step 168: f(x)= 107.18516895112585
# differential_evolution step 169: f(x)= 107.18516895112585
# differential_evolution step 170: f(x)= 107.16789321303888
# differential_evolution step 171: f(x)= 107.16789321303888
# differential_evolution step 172: f(x)= 107.16789321303888
# differential_evolution step 173: f(x)= 107.15489870878274
# differential_evolution step 174: f(x)= 107.15235728031492
# differential_evolution step 175: f(x)= 107.15235728031492
# differential_evolution step 176: f(x)= 107.12666242692316
# differential_evolution step 177: f(x)= 107.12666242692316
# differential_evolution step 178: f(x)= 107.12666242692316
# differential_evolution step 179: f(x)= 107.12666242692316
# differential_evolution step 180: f(x)= 107.12666242692316
# differential_evolution step 181: f(x)= 107.1100987191038
# differential_evolution step 182: f(x)= 107.10490163759285
# differential_evolution step 183: f(x)= 107.10422634329507
# differential_evolution step 184: f(x)= 107.08957919250473
# differential_evolution step 185: f(x)= 107.08957919250473
# differential_evolution step 186: f(x)= 107.08957919250473
# differential_evolution step 187: f(x)= 107.08957919250473
# differential_evolution step 188: f(x)= 107.08957919250473
# differential_evolution step 189: f(x)= 107.08957919250473
# differential_evolution step 190: f(x)= 107.08957919250473
# differential_evolution step 191: f(x)= 107.07493449253067
# differential_evolution step 192: f(x)= 107.07493449253067
# differential_evolution step 193: f(x)= 107.07493449253067
# differential_evolution step 194: f(x)= 107.07493449253067
# differential_evolution step 195: f(x)= 107.07493449253067
# differential_evolution step 196: f(x)= 107.06640597107904
# differential_evolution step 197: f(x)= 107.06640597107904
# differential_evolution step 198: f(x)= 107.06640597107904
# differential_evolution step 199: f(x)= 107.06640597107904
# differential_evolution step 200: f(x)= 107.06536567329303
# differential_evolution step 201: f(x)= 107.06536567329303
# differential_evolution step 202: f(x)= 107.06536567329303
# differential_evolution step 203: f(x)= 107.06077228318291
# differential_evolution step 204: f(x)= 107.06077228318291
# differential_evolution step 205: f(x)= 107.06077228318291
# differential_evolution step 206: f(x)= 107.06077228318291
# differential_evolution step 207: f(x)= 107.05007138736899
# differential_evolution step 208: f(x)= 107.05007138736899
# differential_evolution step 209: f(x)= 107.05007138736899
# differential_evolution step 210: f(x)= 107.05007138736899
# differential_evolution step 211: f(x)= 107.04907987085116
# differential_evolution step 212: f(x)= 107.04907987085116
# differential_evolution step 213: f(x)= 107.04716508633688
# differential_evolution step 214: f(x)= 107.04716508633688
# differential_evolution step 215: f(x)= 107.04716508633688
# differential_evolution step 216: f(x)= 107.04716508633688
# differential_evolution step 217: f(x)= 107.04716508633688
# differential_evolution step 218: f(x)= 107.04716508633688
# differential_evolution step 219: f(x)= 107.04716508633688
# differential_evolution step 220: f(x)= 107.04716508633688
# differential_evolution step 221: f(x)= 107.04716508633688
# differential_evolution step 222: f(x)= 107.04716508633688
# differential_evolution step 223: f(x)= 107.04716508633688
# differential_evolution step 224: f(x)= 107.04716508633688
# differential_evolution step 225: f(x)= 107.0438380165915
# differential_evolution step 226: f(x)= 107.0438380165915
# differential_evolution step 227: f(x)= 107.04153431011426
# differential_evolution step 228: f(x)= 107.04153431011426
# differential_evolution step 229: f(x)= 107.04153431011426
# differential_evolution step 230: f(x)= 107.04127151454914
# differential_evolution step 231: f(x)= 107.04127151454914
# differential_evolution step 232: f(x)= 107.04127151454914
# differential_evolution step 233: f(x)= 107.03770802719083
# differential_evolution step 234: f(x)= 107.03770802719083
# differential_evolution step 235: f(x)= 107.03770802719083
# differential_evolution step 236: f(x)= 107.03770802719083
# differential_evolution step 237: f(x)= 107.03770802719083
# differential_evolution step 238: f(x)= 107.03770802719083
# differential_evolution step 239: f(x)= 107.03770802719083
# differential_evolution step 240: f(x)= 107.03770802719083
# differential_evolution step 241: f(x)= 107.03770802719083
# differential_evolution step 242: f(x)= 107.03770802719083
# differential_evolution step 243: f(x)= 107.03770802719083
# differential_evolution step 244: f(x)= 107.03770802719083
# differential_evolution step 245: f(x)= 107.03770802719083
# differential_evolution step 246: f(x)= 107.03770802719083
# differential_evolution step 247: f(x)= 107.03770802719083
# differential_evolution step 248: f(x)= 107.03461976138678
# differential_evolution step 249: f(x)= 107.03461976138678
# differential_evolution step 250: f(x)= 107.03456109156947
# differential_evolution step 251: f(x)= 107.03456109156947
# differential_evolution step 252: f(x)= 107.03311843006428
# differential_evolution step 253: f(x)= 107.03311843006428
# differential_evolution step 254: f(x)= 107.03311843006428
# differential_evolution step 255: f(x)= 107.03295303630972
# differential_evolution step 256: f(x)= 107.03217490676758
# differential_evolution step 257: f(x)= 107.03217490676758
# differential_evolution step 258: f(x)= 107.03217490676758
# differential_evolution step 259: f(x)= 107.03217490676758
# differential_evolution step 260: f(x)= 107.03054115989966
# differential_evolution step 261: f(x)= 107.03054115989966
# differential_evolution step 262: f(x)= 107.03054115989966
# differential_evolution step 263: f(x)= 107.0290051344678
# differential_evolution step 264: f(x)= 107.0290051344678
# differential_evolution step 265: f(x)= 107.0290051344678
# differential_evolution step 266: f(x)= 107.0290051344678
# differential_evolution step 267: f(x)= 107.0290051344678
# differential_evolution step 268: f(x)= 107.0290051344678
# differential_evolution step 269: f(x)= 107.0290051344678
# differential_evolution step 270: f(x)= 107.0290051344678
# differential_evolution step 271: f(x)= 107.0290051344678
# differential_evolution step 272: f(x)= 107.0290051344678
# differential_evolution step 273: f(x)= 107.0290051344678
# differential_evolution step 274: f(x)= 107.0290051344678
# differential_evolution step 275: f(x)= 107.0290051344678
# differential_evolution step 276: f(x)= 107.0290051344678
# differential_evolution step 277: f(x)= 107.02760786132116
# differential_evolution step 278: f(x)= 107.02760786132116
# differential_evolution step 279: f(x)= 107.02760786132116
# differential_evolution step 280: f(x)= 107.02760786132116
# differential_evolution step 281: f(x)= 107.0267465105518
# differential_evolution step 282: f(x)= 107.0267465105518
# differential_evolution step 283: f(x)= 107.0267465105518
# differential_evolution step 284: f(x)= 107.0267465105518
# differential_evolution step 285: f(x)= 107.0267465105518
# differential_evolution step 286: f(x)= 107.02672235301566
# differential_evolution step 287: f(x)= 107.0261162428296
# differential_evolution step 288: f(x)= 107.0261162428296
# differential_evolution step 289: f(x)= 107.0261162428296
# differential_evolution step 290: f(x)= 107.0261162428296
# differential_evolution step 291: f(x)= 107.0261162428296
# differential_evolution step 292: f(x)= 107.0261162428296
# differential_evolution step 293: f(x)= 107.0261162428296
# differential_evolution step 294: f(x)= 107.0261162428296
# differential_evolution step 295: f(x)= 107.02568195757256
# differential_evolution step 296: f(x)= 107.02568195757256
# differential_evolution step 297: f(x)= 107.02568195757256
# differential_evolution step 298: f(x)= 107.02554100176708
# differential_evolution step 299: f(x)= 107.02554100176708
# differential_evolution step 300: f(x)= 107.02546384068448
# differential_evolution step 301: f(x)= 107.02546384068448
# differential_evolution step 302: f(x)= 107.02544119468767
# differential_evolution step 303: f(x)= 107.02544119468767
# differential_evolution step 304: f(x)= 107.02544119468767
# differential_evolution step 305: f(x)= 107.02544119468767
# differential_evolution step 306: f(x)= 107.02544119468767
# differential_evolution step 307: f(x)= 107.02544119468767
# differential_evolution step 308: f(x)= 107.02544119468767
# differential_evolution step 309: f(x)= 107.02544119468767
# differential_evolution step 310: f(x)= 107.02544119468767
# differential_evolution step 311: f(x)= 107.02544119468767
# differential_evolution step 312: f(x)= 107.02492779440963
# differential_evolution step 313: f(x)= 107.02492779440963
# differential_evolution step 314: f(x)= 107.02492779440963
# differential_evolution step 315: f(x)= 107.02492779440963
# differential_evolution step 316: f(x)= 107.02439303788834
# differential_evolution step 317: f(x)= 107.02439303788834
# differential_evolution step 318: f(x)= 107.02439303788834
# differential_evolution step 319: f(x)= 107.02439303788834
# differential_evolution step 320: f(x)= 107.02439303788834
# differential_evolution step 321: f(x)= 107.02439303788834
# differential_evolution step 322: f(x)= 107.02439303788834
# differential_evolution step 323: f(x)= 107.02439303788834
# differential_evolution step 324: f(x)= 107.02439303788834
# differential_evolution step 325: f(x)= 107.02439303788834
# differential_evolution step 326: f(x)= 107.02439303788834
# differential_evolution step 327: f(x)= 107.02439303788834
# differential_evolution step 328: f(x)= 107.02439303788834
# differential_evolution step 329: f(x)= 107.02439303788834
# differential_evolution step 330: f(x)= 107.02439303788834
# differential_evolution step 331: f(x)= 107.02439303788834
# differential_evolution step 332: f(x)= 107.02439303788834
# differential_evolution step 333: f(x)= 107.02439303788834
# differential_evolution step 334: f(x)= 107.02439303788834
# differential_evolution step 335: f(x)= 107.02439303788834
# differential_evolution step 336: f(x)= 107.02439303788834
# differential_evolution step 337: f(x)= 107.02439303788834
# differential_evolution step 338: f(x)= 107.02439303788834
# differential_evolution step 339: f(x)= 107.02439303788834
# differential_evolution step 340: f(x)= 107.02439044882401
# differential_evolution step 341: f(x)= 107.02439044882401
# differential_evolution step 342: f(x)= 107.02437658896632
# differential_evolution step 343: f(x)= 107.02437658896632
# differential_evolution step 344: f(x)= 107.0243646075991
# differential_evolution step 345: f(x)= 107.0243646075991
# differential_evolution step 346: f(x)= 107.0242785145783
# differential_evolution step 347: f(x)= 107.0242785145783
# differential_evolution step 348: f(x)= 107.0242785145783
# differential_evolution step 349: f(x)= 107.0242785145783
# differential_evolution step 350: f(x)= 107.0242689973571
# differential_evolution step 351: f(x)= 107.0242689973571
# differential_evolution step 352: f(x)= 107.02421897622861
# differential_evolution step 353: f(x)= 107.02416056724384
# differential_evolution step 354: f(x)= 107.02416056724384
# differential_evolution step 355: f(x)= 107.02416056724384
# differential_evolution step 356: f(x)= 107.02416056724384
# differential_evolution step 357: f(x)= 107.02416056724384
# differential_evolution step 358: f(x)= 107.02416056724384
# differential_evolution step 359: f(x)= 107.02416056724384
# differential_evolution step 360: f(x)= 107.02416056724384
# differential_evolution step 361: f(x)= 107.02416056724384
# differential_evolution step 362: f(x)= 107.02416056724384
# differential_evolution step 363: f(x)= 107.02416056724384
# differential_evolution step 364: f(x)= 107.02415598310797
# differential_evolution step 365: f(x)= 107.02415598310797
# differential_evolution step 366: f(x)= 107.0241283417117
# differential_evolution step 367: f(x)= 107.0241283417117
# differential_evolution step 368: f(x)= 107.02412285475143
# differential_evolution step 369: f(x)= 107.02411086236633
# differential_evolution step 370: f(x)= 107.02408112927432
# differential_evolution step 371: f(x)= 107.02408112927432
# differential_evolution step 372: f(x)= 107.02408112927432
# differential_evolution step 373: f(x)= 107.02408112927432
# differential_evolution step 374: f(x)= 107.02408112927432
# differential_evolution step 375: f(x)= 107.02408112927432
# differential_evolution step 376: f(x)= 107.02406186510932
# differential_evolution step 377: f(x)= 107.02406186510932
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=4.3561, x_0=39.8698
# Sérsic 2: I_e=0.1000, r_e=50.0000, n=2.5216, x_0=48.4106
# Sérsic 3: I_e=0.1000, r_e=15.3708, n=2.9508, x_0=58.1217
# Chi quadro minimo: 107.02396253049005
# True

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=4.3561, x_0=39.8698
# Sérsic 2: I_e=0.1000, r_e=50.0000, n=2.5216, x_0=48.4106
# Sérsic 3: I_e=0.1000, r_e=15.3708, n=2.9508, x_0=58.1217
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), 
                                           x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1000, r_e=37.1552, n=4.8521, x_0=39.8950
# Sérsic 2: I_e=0.1000, r_e=26.9489, n=2.8354, x_0=48.5165
# Sérsic 3: I_e=0.1000, r_e=19.7520, n=3.0248, x_0=58.1217
# [4.26186537e-01 1.17445742e+02 3.53975415e+00 1.11123467e-01
#  6.39586650e-01 1.66158179e+02 4.25993036e+00 2.63072056e-01
#  4.35145156e-01 7.51934448e+01 3.16649793e+00 2.04619976e-01]
# 12.60253548791569

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))

real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2109.7768729956792
# differential_evolution step 2: f(x)= 2007.096748064301
# differential_evolution step 3: f(x)= 1616.4075799252892
# differential_evolution step 4: f(x)= 1616.4075799252892
# differential_evolution step 5: f(x)= 1304.1431079595127
# differential_evolution step 6: f(x)= 1304.1431079595127
# differential_evolution step 7: f(x)= 1228.8010051620213
# differential_evolution step 8: f(x)= 1228.8010051620213
# differential_evolution step 9: f(x)= 1228.8010051620213
# differential_evolution step 10: f(x)= 1228.8010051620213
# differential_evolution step 11: f(x)= 1228.8010051620213
# differential_evolution step 12: f(x)= 1177.093060268218
# differential_evolution step 13: f(x)= 1177.093060268218
# differential_evolution step 14: f(x)= 1177.093060268218
# differential_evolution step 15: f(x)= 1126.2261239907386
# differential_evolution step 16: f(x)= 1126.2261239907386
# differential_evolution step 17: f(x)= 1126.2261239907386
# differential_evolution step 18: f(x)= 1102.4817349801563
# differential_evolution step 19: f(x)= 1102.4817349801563
# differential_evolution step 20: f(x)= 1102.4817349801563
# differential_evolution step 21: f(x)= 1102.4817349801563
# differential_evolution step 22: f(x)= 960.711962124572
# differential_evolution step 23: f(x)= 960.711962124572
# differential_evolution step 24: f(x)= 960.711962124572
# differential_evolution step 25: f(x)= 960.711962124572
# differential_evolution step 26: f(x)= 960.711962124572
# differential_evolution step 27: f(x)= 953.4848501076573
# differential_evolution step 28: f(x)= 948.1852331656303
# differential_evolution step 29: f(x)= 948.1852331656303
# differential_evolution step 30: f(x)= 948.1852331656303
# differential_evolution step 31: f(x)= 948.1852331656303
# differential_evolution step 32: f(x)= 932.0158449547934
# differential_evolution step 33: f(x)= 923.532359884381
# differential_evolution step 34: f(x)= 903.6255761949602
# differential_evolution step 35: f(x)= 899.6550799839645
# differential_evolution step 36: f(x)= 899.6550799839645
# differential_evolution step 37: f(x)= 899.6550799839645
# differential_evolution step 38: f(x)= 899.6550799839645
# differential_evolution step 39: f(x)= 899.6550799839645
# differential_evolution step 40: f(x)= 898.3721911445131
# differential_evolution step 41: f(x)= 898.3721911445131
# differential_evolution step 42: f(x)= 898.3721911445131
# differential_evolution step 43: f(x)= 898.3721911445131
# differential_evolution step 44: f(x)= 898.3721911445131
# differential_evolution step 45: f(x)= 898.3721911445131
# differential_evolution step 46: f(x)= 898.3721911445131
# differential_evolution step 47: f(x)= 898.3721911445131
# differential_evolution step 48: f(x)= 898.3721911445131
# differential_evolution step 49: f(x)= 883.2553999331354
# differential_evolution step 50: f(x)= 883.2553999331354
# differential_evolution step 51: f(x)= 883.2553999331354
# differential_evolution step 52: f(x)= 883.2553999331354
# differential_evolution step 53: f(x)= 883.2553999331354
# differential_evolution step 54: f(x)= 877.3901830011858
# differential_evolution step 55: f(x)= 877.3901830011858
# differential_evolution step 56: f(x)= 874.1609721755672
# differential_evolution step 57: f(x)= 869.1713828098831
# differential_evolution step 58: f(x)= 867.8535313199254
# differential_evolution step 59: f(x)= 867.8535313199254
# differential_evolution step 60: f(x)= 866.935704635349
# differential_evolution step 61: f(x)= 852.7431354455144
# differential_evolution step 62: f(x)= 852.7431354455144
# differential_evolution step 63: f(x)= 849.3621152125063
# differential_evolution step 64: f(x)= 849.3621152125063
# differential_evolution step 65: f(x)= 849.3621152125063
# differential_evolution step 66: f(x)= 849.3621152125063
# differential_evolution step 67: f(x)= 849.3621152125063
# differential_evolution step 68: f(x)= 849.3621152125063
# differential_evolution step 69: f(x)= 849.0677396491736
# differential_evolution step 70: f(x)= 849.0677396491736
# differential_evolution step 71: f(x)= 849.0677396491736
# differential_evolution step 72: f(x)= 838.7891343894131
# differential_evolution step 73: f(x)= 838.7891343894131
# differential_evolution step 74: f(x)= 838.7891343894131
# differential_evolution step 75: f(x)= 838.7891343894131
# differential_evolution step 76: f(x)= 838.7891343894131
# differential_evolution step 77: f(x)= 838.7891343894131
# differential_evolution step 78: f(x)= 838.7891343894131
# differential_evolution step 79: f(x)= 838.7891343894131
# differential_evolution step 80: f(x)= 838.7891343894131
# differential_evolution step 81: f(x)= 838.7891343894131
# differential_evolution step 82: f(x)= 838.7891343894131
# differential_evolution step 83: f(x)= 838.7891343894131
# differential_evolution step 84: f(x)= 838.7891343894131
# differential_evolution step 85: f(x)= 838.7891343894131
# differential_evolution step 86: f(x)= 837.4471355252084
# differential_evolution step 87: f(x)= 837.4471355252084
# differential_evolution step 88: f(x)= 837.4471355252084
# differential_evolution step 89: f(x)= 837.4471355252084
# differential_evolution step 90: f(x)= 837.4471355252084
# differential_evolution step 91: f(x)= 837.4471355252084
# differential_evolution step 92: f(x)= 836.4702470148509
# differential_evolution step 93: f(x)= 836.4702470148509
# differential_evolution step 94: f(x)= 836.4702470148509
# differential_evolution step 95: f(x)= 836.4518075215096
# differential_evolution step 96: f(x)= 836.4518075215096
# differential_evolution step 97: f(x)= 835.8176039738748
# differential_evolution step 98: f(x)= 834.9699827020409
# differential_evolution step 99: f(x)= 833.6402785286106
# differential_evolution step 100: f(x)= 833.6402785286106
# differential_evolution step 101: f(x)= 833.6402785286106
# differential_evolution step 102: f(x)= 833.6402785286106
# differential_evolution step 103: f(x)= 833.6402785286106
# differential_evolution step 104: f(x)= 832.2821332985727
# differential_evolution step 105: f(x)= 832.2821332985727
# differential_evolution step 106: f(x)= 832.2821332985727
# differential_evolution step 107: f(x)= 832.2821332985727
# differential_evolution step 108: f(x)= 832.2821332985727
# differential_evolution step 109: f(x)= 832.1992634171409
# differential_evolution step 110: f(x)= 832.1992634171409
# differential_evolution step 111: f(x)= 832.1992634171409
# differential_evolution step 112: f(x)= 832.1992634171409
# differential_evolution step 113: f(x)= 831.3832313111101
# differential_evolution step 114: f(x)= 831.3832313111101
# differential_evolution step 115: f(x)= 831.3832313111101
# differential_evolution step 116: f(x)= 831.3832313111101
# differential_evolution step 117: f(x)= 831.2827927358302
# differential_evolution step 118: f(x)= 831.2827927358302
# differential_evolution step 119: f(x)= 831.2827927358302
# differential_evolution step 120: f(x)= 831.2827927358302
# differential_evolution step 121: f(x)= 831.2827927358302
# differential_evolution step 122: f(x)= 829.1601216457078
# differential_evolution step 123: f(x)= 829.1601216457078
# differential_evolution step 124: f(x)= 829.1601216457078
# differential_evolution step 125: f(x)= 829.1601216457078
# differential_evolution step 126: f(x)= 829.1601216457078
# differential_evolution step 127: f(x)= 829.1601216457078
# differential_evolution step 128: f(x)= 829.1601216457078
# differential_evolution step 129: f(x)= 829.1601216457078
# differential_evolution step 130: f(x)= 829.1601216457078
# differential_evolution step 131: f(x)= 829.1601216457078
# differential_evolution step 132: f(x)= 829.1601216457078
# differential_evolution step 133: f(x)= 829.1601216457078
# differential_evolution step 134: f(x)= 829.1601216457078
# differential_evolution step 135: f(x)= 829.1601216457078
# differential_evolution step 136: f(x)= 829.1601216457078
# differential_evolution step 137: f(x)= 829.1601216457078
# differential_evolution step 138: f(x)= 829.1601216457078
# differential_evolution step 139: f(x)= 829.1601216457078
# differential_evolution step 140: f(x)= 829.1601216457078
# differential_evolution step 141: f(x)= 829.1601216457078
# differential_evolution step 142: f(x)= 829.1601216457078
# differential_evolution step 143: f(x)= 829.1601216457078
# differential_evolution step 144: f(x)= 829.1601216457078
# differential_evolution step 145: f(x)= 829.1601216457078
# differential_evolution step 146: f(x)= 829.1601216457078
# differential_evolution step 147: f(x)= 829.1601216457078
# differential_evolution step 148: f(x)= 829.1601216457078
# differential_evolution step 149: f(x)= 829.1601216457078
# differential_evolution step 150: f(x)= 829.1601216457078
# differential_evolution step 151: f(x)= 829.1601216457078
# differential_evolution step 152: f(x)= 828.8630671527249
# differential_evolution step 153: f(x)= 828.8630671527249
# differential_evolution step 154: f(x)= 828.8630671527249
# differential_evolution step 155: f(x)= 828.8630671527249
# differential_evolution step 156: f(x)= 828.8630671527249
# differential_evolution step 157: f(x)= 828.8630671527249
# differential_evolution step 158: f(x)= 828.8630671527249
# differential_evolution step 159: f(x)= 828.8630671527249
# differential_evolution step 160: f(x)= 828.8630671527249
# differential_evolution step 161: f(x)= 828.8630671527249
# differential_evolution step 162: f(x)= 828.8630671527249
# differential_evolution step 163: f(x)= 828.8630671527249
# differential_evolution step 164: f(x)= 828.8630671527249
# differential_evolution step 165: f(x)= 828.8630671527249
# differential_evolution step 166: f(x)= 828.8630671527249
# differential_evolution step 167: f(x)= 828.8630671527249
# differential_evolution step 168: f(x)= 828.8630671527249
# differential_evolution step 169: f(x)= 828.8630671527249
# differential_evolution step 170: f(x)= 828.8630671527249
# differential_evolution step 171: f(x)= 828.7566864285079
# differential_evolution step 172: f(x)= 828.5513809209457
# differential_evolution step 173: f(x)= 828.5513809209457
# differential_evolution step 174: f(x)= 828.5513809209457
# differential_evolution step 175: f(x)= 828.5513809209457
# differential_evolution step 176: f(x)= 828.5513809209457
# differential_evolution step 177: f(x)= 828.5513809209457
# differential_evolution step 178: f(x)= 828.5513809209457
# differential_evolution step 179: f(x)= 828.4357676673926
# differential_evolution step 180: f(x)= 828.4357676673926
# differential_evolution step 181: f(x)= 828.4357676673926
# differential_evolution step 182: f(x)= 828.3248919799369
# differential_evolution step 183: f(x)= 828.3248919799369
# differential_evolution step 184: f(x)= 828.3248919799369
# differential_evolution step 185: f(x)= 828.3248919799369
# differential_evolution step 186: f(x)= 828.3248919799369
# differential_evolution step 187: f(x)= 828.3248919799369
# differential_evolution step 188: f(x)= 828.3248919799369
# differential_evolution step 189: f(x)= 828.3248919799369
# differential_evolution step 190: f(x)= 828.3248919799369
# differential_evolution step 191: f(x)= 828.3248919799369
# differential_evolution step 192: f(x)= 828.3248919799369
# differential_evolution step 193: f(x)= 828.2956309322957
# differential_evolution step 194: f(x)= 828.2956309322957
# differential_evolution step 195: f(x)= 828.2576740916062
# differential_evolution step 196: f(x)= 828.2576740916062
# differential_evolution step 197: f(x)= 828.2576740916062
# differential_evolution step 198: f(x)= 828.2382696319482
# differential_evolution step 199: f(x)= 828.2375002339433
# differential_evolution step 200: f(x)= 828.2375002339433
# differential_evolution step 201: f(x)= 828.2375002339433
# differential_evolution step 202: f(x)= 828.2375002339433
# differential_evolution step 203: f(x)= 828.2073281495842
# differential_evolution step 204: f(x)= 828.2073281495842
# differential_evolution step 205: f(x)= 828.2073281495842
# differential_evolution step 206: f(x)= 828.2073281495842
# differential_evolution step 207: f(x)= 828.1875221059531
# differential_evolution step 208: f(x)= 828.1875221059531
# differential_evolution step 209: f(x)= 828.1406202669225
# differential_evolution step 210: f(x)= 828.1406202669225
# differential_evolution step 211: f(x)= 828.1288513454281
# differential_evolution step 212: f(x)= 828.1288513454281
# differential_evolution step 213: f(x)= 828.1288513454281
# differential_evolution step 214: f(x)= 828.1288513454281
# differential_evolution step 215: f(x)= 828.0757832969889
# differential_evolution step 216: f(x)= 828.0757832969889
# differential_evolution step 217: f(x)= 828.0757832969889
# differential_evolution step 218: f(x)= 828.0752328955648
# differential_evolution step 219: f(x)= 828.0752328955648
# differential_evolution step 220: f(x)= 828.0398946993906
# differential_evolution step 221: f(x)= 828.0398946993906
# differential_evolution step 222: f(x)= 828.0346179074292
# differential_evolution step 223: f(x)= 828.0346179074292
# differential_evolution step 224: f(x)= 828.0240908691394
# differential_evolution step 225: f(x)= 828.0090674879737
# differential_evolution step 226: f(x)= 828.0090674879737
# differential_evolution step 227: f(x)= 828.0090674879737
# differential_evolution step 228: f(x)= 828.0090674879737
# differential_evolution step 229: f(x)= 828.0090674879737
# differential_evolution step 230: f(x)= 828.0090674879737
# differential_evolution step 231: f(x)= 827.9976012966954
# differential_evolution step 232: f(x)= 827.9876058255957
# differential_evolution step 233: f(x)= 827.9876058255957
# differential_evolution step 234: f(x)= 827.9876058255957
# differential_evolution step 235: f(x)= 827.9876058255957
# differential_evolution step 236: f(x)= 827.9876058255957
# differential_evolution step 237: f(x)= 827.9876058255957
# differential_evolution step 238: f(x)= 827.9876058255957
# differential_evolution step 239: f(x)= 827.9676092627523
# differential_evolution step 240: f(x)= 827.9676092627523
# differential_evolution step 241: f(x)= 827.9676092627523
# differential_evolution step 242: f(x)= 827.9676092627523
# differential_evolution step 243: f(x)= 827.9676092627523
# differential_evolution step 244: f(x)= 827.9676092627523
# differential_evolution step 245: f(x)= 827.9676092627523
# differential_evolution step 246: f(x)= 827.9676092627523
# differential_evolution step 247: f(x)= 827.9676092627523
# differential_evolution step 248: f(x)= 827.9676092627523
# differential_evolution step 249: f(x)= 827.9585421267401
# differential_evolution step 250: f(x)= 827.9585421267401
# differential_evolution step 251: f(x)= 827.9503561086511
# differential_evolution step 252: f(x)= 827.9503561086511
# differential_evolution step 253: f(x)= 827.9462554485684
# differential_evolution step 254: f(x)= 827.9462554485684
# differential_evolution step 255: f(x)= 827.9283937440711
# differential_evolution step 256: f(x)= 827.9283937440711
# differential_evolution step 257: f(x)= 827.9237814343811
# differential_evolution step 258: f(x)= 827.9237814343811
# differential_evolution step 259: f(x)= 827.9237814343811
# differential_evolution step 260: f(x)= 827.9237814343811
# differential_evolution step 261: f(x)= 827.9237814343811
# differential_evolution step 262: f(x)= 827.9237814343811
# differential_evolution step 263: f(x)= 827.9237814343811
# differential_evolution step 264: f(x)= 827.9237814343811
# differential_evolution step 265: f(x)= 827.9237814343811
# differential_evolution step 266: f(x)= 827.9237814343811
# differential_evolution step 267: f(x)= 827.9237814343811
# differential_evolution step 268: f(x)= 827.9144155034124
# differential_evolution step 269: f(x)= 827.9144155034124
# differential_evolution step 270: f(x)= 827.9144155034124
# differential_evolution step 271: f(x)= 827.914274008005
# differential_evolution step 272: f(x)= 827.914274008005
# differential_evolution step 273: f(x)= 827.914274008005
# differential_evolution step 274: f(x)= 827.914274008005
# differential_evolution step 275: f(x)= 827.914274008005
# differential_evolution step 276: f(x)= 827.914274008005
# differential_evolution step 277: f(x)= 827.9106179077838
# differential_evolution step 278: f(x)= 827.9106179077838
# differential_evolution step 279: f(x)= 827.9049618346161
# differential_evolution step 280: f(x)= 827.9049618346161
# differential_evolution step 281: f(x)= 827.9049618346161
# differential_evolution step 282: f(x)= 827.9049618346161
# differential_evolution step 283: f(x)= 827.9049618346161
# differential_evolution step 284: f(x)= 827.9049618346161
# differential_evolution step 285: f(x)= 827.9049618346161
# differential_evolution step 286: f(x)= 827.9049618346161
# differential_evolution step 287: f(x)= 827.9049618346161
# differential_evolution step 288: f(x)= 827.9026810099172
# differential_evolution step 289: f(x)= 827.9011923683855
# differential_evolution step 290: f(x)= 827.8974280720598
# differential_evolution step 291: f(x)= 827.8974280720598
# differential_evolution step 292: f(x)= 827.8974280720598
# differential_evolution step 293: f(x)= 827.8974280720598
# differential_evolution step 294: f(x)= 827.8974280720598
# differential_evolution step 295: f(x)= 827.8974280720598
# differential_evolution step 296: f(x)= 827.8941969285579
# differential_evolution step 297: f(x)= 827.8941969285579
# differential_evolution step 298: f(x)= 827.8941969285579
# differential_evolution step 299: f(x)= 827.8941969285579
# differential_evolution step 300: f(x)= 827.8941549704937
# differential_evolution step 301: f(x)= 827.8941549704937
# differential_evolution step 302: f(x)= 827.8931074274767
# differential_evolution step 303: f(x)= 827.8931074274767
# differential_evolution step 304: f(x)= 827.8931074274767
# differential_evolution step 305: f(x)= 827.8914201814626
# differential_evolution step 306: f(x)= 827.8914201814626
# differential_evolution step 307: f(x)= 827.8876075401214
# differential_evolution step 308: f(x)= 827.8816044180896
# differential_evolution step 309: f(x)= 827.8816044180896
# differential_evolution step 310: f(x)= 827.8816044180896
# differential_evolution step 311: f(x)= 827.8816044180896
# differential_evolution step 312: f(x)= 827.8816044180896
# differential_evolution step 313: f(x)= 827.8816044180896
# differential_evolution step 314: f(x)= 827.8792676986105
# differential_evolution step 315: f(x)= 827.8792676986105
# differential_evolution step 316: f(x)= 827.8792676986105
# differential_evolution step 317: f(x)= 827.8792676986105
# differential_evolution step 318: f(x)= 827.8792676986105
# differential_evolution step 319: f(x)= 827.8792531325422
# differential_evolution step 320: f(x)= 827.8792531325422
# differential_evolution step 321: f(x)= 827.8792531325422
# differential_evolution step 322: f(x)= 827.8792531325422
# differential_evolution step 323: f(x)= 827.8792531325422
# differential_evolution step 324: f(x)= 827.8792531325422
# differential_evolution step 325: f(x)= 827.8792531325422
# differential_evolution step 326: f(x)= 827.878505461317
# differential_evolution step 327: f(x)= 827.878505461317
# differential_evolution step 328: f(x)= 827.8761839463349
# differential_evolution step 329: f(x)= 827.8758813054894
# differential_evolution step 330: f(x)= 827.8747614898135
# differential_evolution step 331: f(x)= 827.8747614898135
# differential_evolution step 332: f(x)= 827.8747614898135
# differential_evolution step 333: f(x)= 827.8733461746954
# differential_evolution step 334: f(x)= 827.8733461746954
# differential_evolution step 335: f(x)= 827.8733461746954
# differential_evolution step 336: f(x)= 827.8733461746954
# differential_evolution step 337: f(x)= 827.8733461746954
# differential_evolution step 338: f(x)= 827.8716970696983
# differential_evolution step 339: f(x)= 827.8716970696983
# differential_evolution step 340: f(x)= 827.8716970696983
# differential_evolution step 341: f(x)= 827.8716970696983
# differential_evolution step 342: f(x)= 827.8716970696983
# differential_evolution step 343: f(x)= 827.8716970696983
# differential_evolution step 344: f(x)= 827.8716970696983
# differential_evolution step 345: f(x)= 827.8716970696983
# differential_evolution step 346: f(x)= 827.8715025396114
# differential_evolution step 347: f(x)= 827.8715025396114
# differential_evolution step 348: f(x)= 827.8715025396114
# differential_evolution step 349: f(x)= 827.8715025396114
# differential_evolution step 350: f(x)= 827.8715025396114
# differential_evolution step 351: f(x)= 827.8715025396114
# differential_evolution step 352: f(x)= 827.8701759683538
# differential_evolution step 353: f(x)= 827.8701759683538
# differential_evolution step 354: f(x)= 827.8701759683538
# differential_evolution step 355: f(x)= 827.8701759683538
# differential_evolution step 356: f(x)= 827.8701759683538
# differential_evolution step 357: f(x)= 827.8701759683538
# differential_evolution step 358: f(x)= 827.8701759683538
# differential_evolution step 359: f(x)= 827.8696200458648
# differential_evolution step 360: f(x)= 827.8696200458648
# differential_evolution step 361: f(x)= 827.8696200458648
# differential_evolution step 362: f(x)= 827.8696200458648
# differential_evolution step 363: f(x)= 827.8696200458648
# differential_evolution step 364: f(x)= 827.8696200458648
# differential_evolution step 365: f(x)= 827.8696200458648
# differential_evolution step 366: f(x)= 827.8696200458648
# differential_evolution step 367: f(x)= 827.8696200458648
# differential_evolution step 368: f(x)= 827.8695416404638
# differential_evolution step 369: f(x)= 827.868541451061
# differential_evolution step 370: f(x)= 827.868541451061
# differential_evolution step 371: f(x)= 827.868541451061
# differential_evolution step 372: f(x)= 827.868541451061
# differential_evolution step 373: f(x)= 827.868541451061
# differential_evolution step 374: f(x)= 827.868541451061
# differential_evolution step 375: f(x)= 827.868541451061
# differential_evolution step 376: f(x)= 827.868541451061
# differential_evolution step 377: f(x)= 827.868541451061
# differential_evolution step 378: f(x)= 827.8682578064196
# differential_evolution step 379: f(x)= 827.8682578064196
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=5.2575, x_0=39.3746
# Sérsic 2: I_e=0.1000, r_e=49.9999, n=3.0907, x_0=48.7750
# Sérsic 3: I_e=0.1000, r_e=49.9993, n=2.6903, x_0=56.8897
# Chi quadro minimo: 827.8682578064196
# True

# %%
# Plots:
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')
# Out:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=5.2575, x_0=39.3746
# Sérsic 2: I_e=0.1000, r_e=49.9999, n=3.0907, x_0=48.7750
# Sérsic 3: I_e=0.1000, r_e=49.9993, n=2.6903, x_0=56.8897
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = real_errors_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1000, r_e=33.9586, n=6.0531, x_0=39.3253
# Sérsic 2: I_e=0.1000, r_e=28.4905, n=3.6173, x_0=49.1008
# Sérsic 3: I_e=0.1000, r_e=21.6193, n=3.4535, x_0=56.8820
# [5.97509037e-01 1.35876390e+02 5.75232369e+00 1.43853739e-01
#  8.34056217e-01 2.01129099e+02 6.01517663e+00 2.34195699e-01
#  5.83134145e-01 1.04253622e+02 4.42008736e+00 2.37377586e-01]
# 32.5147633482137

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
x_axes = np.arange(0, 100, 1)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))

real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[3])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 393.66947003111744
# differential_evolution step 2: f(x)= 188.88083999065364
# differential_evolution step 3: f(x)= 188.88083999065364
# differential_evolution step 4: f(x)= 188.88083999065364
# differential_evolution step 5: f(x)= 188.88083999065364
# differential_evolution step 6: f(x)= 188.88083999065364
# differential_evolution step 7: f(x)= 188.88083999065364
# differential_evolution step 8: f(x)= 188.88083999065364
# differential_evolution step 9: f(x)= 188.88083999065364
# differential_evolution step 10: f(x)= 188.88083999065364
# differential_evolution step 11: f(x)= 188.88083999065364
# differential_evolution step 12: f(x)= 184.46149839909867
# differential_evolution step 13: f(x)= 184.46149839909867
# differential_evolution step 14: f(x)= 184.46149839909867
# differential_evolution step 15: f(x)= 184.46149839909867
# differential_evolution step 16: f(x)= 184.46149839909867
# differential_evolution step 17: f(x)= 184.07809291787
# differential_evolution step 18: f(x)= 184.07809291787
# differential_evolution step 19: f(x)= 184.07809291787
# differential_evolution step 20: f(x)= 184.07809291787
# differential_evolution step 21: f(x)= 184.07809291787
# differential_evolution step 22: f(x)= 184.07809291787
# differential_evolution step 23: f(x)= 177.58561881503826
# differential_evolution step 24: f(x)= 177.58561881503826
# differential_evolution step 25: f(x)= 177.58561881503826
# differential_evolution step 26: f(x)= 167.3339975354231
# differential_evolution step 27: f(x)= 167.3339975354231
# differential_evolution step 28: f(x)= 163.1477176216208
# differential_evolution step 29: f(x)= 163.1477176216208
# differential_evolution step 30: f(x)= 163.1477176216208
# differential_evolution step 31: f(x)= 163.1477176216208
# differential_evolution step 32: f(x)= 163.1477176216208
# differential_evolution step 33: f(x)= 163.1477176216208
# differential_evolution step 34: f(x)= 163.1477176216208
# differential_evolution step 35: f(x)= 163.1477176216208
# differential_evolution step 36: f(x)= 161.11673244961335
# differential_evolution step 37: f(x)= 154.18312470175505
# differential_evolution step 38: f(x)= 154.18312470175505
# differential_evolution step 39: f(x)= 154.18312470175505
# differential_evolution step 40: f(x)= 154.18312470175505
# differential_evolution step 41: f(x)= 154.18312470175505
# differential_evolution step 42: f(x)= 154.1278254661507
# differential_evolution step 43: f(x)= 154.1278254661507
# differential_evolution step 44: f(x)= 154.1278254661507
# differential_evolution step 45: f(x)= 154.1278254661507
# differential_evolution step 46: f(x)= 151.96042791058983
# differential_evolution step 47: f(x)= 151.96042791058983
# differential_evolution step 48: f(x)= 151.96042791058983
# differential_evolution step 49: f(x)= 151.96042791058983
# differential_evolution step 50: f(x)= 151.96042791058983
# differential_evolution step 51: f(x)= 151.8516150614671
# differential_evolution step 52: f(x)= 151.27293188457827
# differential_evolution step 53: f(x)= 149.64194235753834
# differential_evolution step 54: f(x)= 149.64194235753834
# differential_evolution step 55: f(x)= 149.64194235753834
# differential_evolution step 56: f(x)= 149.64194235753834
# differential_evolution step 57: f(x)= 149.64194235753834
# differential_evolution step 58: f(x)= 149.64194235753834
# differential_evolution step 59: f(x)= 149.64194235753834
# differential_evolution step 60: f(x)= 149.64194235753834
# differential_evolution step 61: f(x)= 149.64194235753834
# differential_evolution step 62: f(x)= 149.64194235753834
# differential_evolution step 63: f(x)= 149.64194235753834
# differential_evolution step 64: f(x)= 149.64194235753834
# differential_evolution step 65: f(x)= 149.47616127473992
# differential_evolution step 66: f(x)= 149.47616127473992
# differential_evolution step 67: f(x)= 149.47616127473992
# differential_evolution step 68: f(x)= 149.47616127473992
# differential_evolution step 69: f(x)= 149.47616127473992
# differential_evolution step 70: f(x)= 148.82107835494705
# differential_evolution step 71: f(x)= 148.82107835494705
# differential_evolution step 72: f(x)= 148.82107835494705
# differential_evolution step 73: f(x)= 148.82107835494705
# differential_evolution step 74: f(x)= 148.82107835494705
# differential_evolution step 75: f(x)= 148.82107835494705
# differential_evolution step 76: f(x)= 148.82107835494705
# differential_evolution step 77: f(x)= 148.82107835494705
# differential_evolution step 78: f(x)= 148.82107835494705
# differential_evolution step 79: f(x)= 148.82107835494705
# differential_evolution step 80: f(x)= 148.762904206153
# differential_evolution step 81: f(x)= 148.51607354458034
# differential_evolution step 82: f(x)= 148.51607354458034
# differential_evolution step 83: f(x)= 148.47001471206482
# differential_evolution step 84: f(x)= 148.47001471206482
# differential_evolution step 85: f(x)= 148.47001471206482
# differential_evolution step 86: f(x)= 148.47001471206482
# differential_evolution step 87: f(x)= 148.4587317240483
# differential_evolution step 88: f(x)= 148.4587317240483
# differential_evolution step 89: f(x)= 148.3973733487211
# differential_evolution step 90: f(x)= 148.3973733487211
# differential_evolution step 91: f(x)= 148.3973733487211
# differential_evolution step 92: f(x)= 148.3973733487211
# differential_evolution step 93: f(x)= 148.37884005396234
# differential_evolution step 94: f(x)= 148.26520075277213
# differential_evolution step 95: f(x)= 148.15380351028756
# differential_evolution step 96: f(x)= 148.15380351028756
# differential_evolution step 97: f(x)= 148.15380351028756
# differential_evolution step 98: f(x)= 148.15380351028756
# differential_evolution step 99: f(x)= 148.15380351028756
# differential_evolution step 100: f(x)= 148.15380351028756
# differential_evolution step 101: f(x)= 148.15380351028756
# differential_evolution step 102: f(x)= 148.15380351028756
# differential_evolution step 103: f(x)= 148.15380351028756
# differential_evolution step 104: f(x)= 148.15380351028756
# differential_evolution step 105: f(x)= 148.15380351028756
# differential_evolution step 106: f(x)= 148.0838445746933
# differential_evolution step 107: f(x)= 148.0838445746933
# differential_evolution step 108: f(x)= 147.9369423935395
# differential_evolution step 109: f(x)= 147.9369423935395
# differential_evolution step 110: f(x)= 147.9369423935395
# differential_evolution step 111: f(x)= 147.9369423935395
# differential_evolution step 112: f(x)= 147.9369423935395
# differential_evolution step 113: f(x)= 147.9369423935395
# differential_evolution step 114: f(x)= 147.9369423935395
# differential_evolution step 115: f(x)= 147.9369423935395
# differential_evolution step 116: f(x)= 147.88901210860035
# differential_evolution step 117: f(x)= 147.88901210860035
# differential_evolution step 118: f(x)= 147.88901210860035
# differential_evolution step 119: f(x)= 147.88901210860035
# differential_evolution step 120: f(x)= 147.88901210860035
# differential_evolution step 121: f(x)= 147.88901210860035
# differential_evolution step 122: f(x)= 147.88901210860035
# differential_evolution step 123: f(x)= 147.88901210860035
# differential_evolution step 124: f(x)= 147.88901210860035
# differential_evolution step 125: f(x)= 147.88901210860035
# differential_evolution step 126: f(x)= 147.88901210860035
# differential_evolution step 127: f(x)= 147.88901210860035
# differential_evolution step 128: f(x)= 147.85912422669472
# differential_evolution step 129: f(x)= 147.81938756031215
# differential_evolution step 130: f(x)= 147.81938756031215
# differential_evolution step 131: f(x)= 147.81938756031215
# differential_evolution step 132: f(x)= 147.81938756031215
# differential_evolution step 133: f(x)= 147.81938756031215
# differential_evolution step 134: f(x)= 147.81938756031215
# differential_evolution step 135: f(x)= 147.81938756031215
# differential_evolution step 136: f(x)= 147.81938756031215
# differential_evolution step 137: f(x)= 147.81938756031215
# differential_evolution step 138: f(x)= 147.81326131992253
# differential_evolution step 139: f(x)= 147.81326131992253
# differential_evolution step 140: f(x)= 147.81326131992253
# differential_evolution step 141: f(x)= 147.81326131992253
# differential_evolution step 142: f(x)= 147.81326131992253
# differential_evolution step 143: f(x)= 147.81326131992253
# differential_evolution step 144: f(x)= 147.81326131992253
# differential_evolution step 145: f(x)= 147.81326131992253
# differential_evolution step 146: f(x)= 147.81326131992253
# differential_evolution step 147: f(x)= 147.81326131992253
# differential_evolution step 148: f(x)= 147.7859198874413
# differential_evolution step 149: f(x)= 147.7859198874413
# differential_evolution step 150: f(x)= 147.7859198874413
# differential_evolution step 151: f(x)= 147.7859198874413
# differential_evolution step 152: f(x)= 147.7859198874413
# differential_evolution step 153: f(x)= 147.7859198874413
# differential_evolution step 154: f(x)= 147.72350379743952
# differential_evolution step 155: f(x)= 147.72350379743952
# differential_evolution step 156: f(x)= 147.72350379743952
# differential_evolution step 157: f(x)= 147.72350379743952
# differential_evolution step 158: f(x)= 147.72350379743952
# differential_evolution step 159: f(x)= 147.72350379743952
# differential_evolution step 160: f(x)= 147.72350379743952
# differential_evolution step 161: f(x)= 147.72350379743952
# differential_evolution step 162: f(x)= 147.72350379743952
# differential_evolution step 163: f(x)= 147.72350379743952
# differential_evolution step 164: f(x)= 147.72350379743952
# differential_evolution step 165: f(x)= 147.72350379743952
# differential_evolution step 166: f(x)= 147.72350379743952
# differential_evolution step 167: f(x)= 147.7131285764052
# differential_evolution step 168: f(x)= 147.7131285764052
# differential_evolution step 169: f(x)= 147.70171676549646
# differential_evolution step 170: f(x)= 147.70171676549646
# differential_evolution step 171: f(x)= 147.69889006166753
# differential_evolution step 172: f(x)= 147.69889006166753
# differential_evolution step 173: f(x)= 147.69889006166753
# differential_evolution step 174: f(x)= 147.66232927801036
# differential_evolution step 175: f(x)= 147.66232927801036
# differential_evolution step 176: f(x)= 147.66232927801036
# differential_evolution step 177: f(x)= 147.66232927801036
# differential_evolution step 178: f(x)= 147.66232927801036
# differential_evolution step 179: f(x)= 147.66232927801036
# differential_evolution step 180: f(x)= 147.66232927801036
# differential_evolution step 181: f(x)= 147.66232927801036
# differential_evolution step 182: f(x)= 147.66232927801036
# differential_evolution step 183: f(x)= 147.66232927801036
# differential_evolution step 184: f(x)= 147.66232927801036
# differential_evolution step 185: f(x)= 147.6310553687328
# differential_evolution step 186: f(x)= 147.6310553687328
# differential_evolution step 187: f(x)= 147.6310553687328
# differential_evolution step 188: f(x)= 147.6178787031499
# differential_evolution step 189: f(x)= 147.6178787031499
# differential_evolution step 190: f(x)= 147.6178787031499
# differential_evolution step 191: f(x)= 147.6178787031499
# differential_evolution step 192: f(x)= 147.6178787031499
# differential_evolution step 193: f(x)= 147.6178787031499
# differential_evolution step 194: f(x)= 147.6178787031499
# differential_evolution step 195: f(x)= 147.6178787031499
# differential_evolution step 196: f(x)= 147.6178787031499
# differential_evolution step 197: f(x)= 147.6178787031499
# differential_evolution step 198: f(x)= 147.6178787031499
# differential_evolution step 199: f(x)= 147.6178787031499
# differential_evolution step 200: f(x)= 147.57344280552604
# differential_evolution step 201: f(x)= 147.57344280552604
# differential_evolution step 202: f(x)= 147.57344280552604
# differential_evolution step 203: f(x)= 147.57344280552604
# differential_evolution step 204: f(x)= 147.57121227317342
# differential_evolution step 205: f(x)= 147.57121227317342
# differential_evolution step 206: f(x)= 147.57121227317342
# differential_evolution step 207: f(x)= 147.57121227317342
# differential_evolution step 208: f(x)= 147.57121227317342
# differential_evolution step 209: f(x)= 147.57121227317342
# differential_evolution step 210: f(x)= 147.57121227317342
# differential_evolution step 211: f(x)= 147.57121227317342
# differential_evolution step 212: f(x)= 147.57121227317342
# differential_evolution step 213: f(x)= 147.57121227317342
# differential_evolution step 214: f(x)= 147.57121227317342
# differential_evolution step 215: f(x)= 147.57121227317342
# differential_evolution step 216: f(x)= 147.57121227317342
# differential_evolution step 217: f(x)= 147.57121227317342
# differential_evolution step 218: f(x)= 147.56428688621904
# differential_evolution step 219: f(x)= 147.56428688621904
# differential_evolution step 220: f(x)= 147.56428688621904
# differential_evolution step 221: f(x)= 147.55998047652292
# differential_evolution step 222: f(x)= 147.55998047652292
# differential_evolution step 223: f(x)= 147.5512068812569
# differential_evolution step 224: f(x)= 147.5512068812569
# differential_evolution step 225: f(x)= 147.5512068812569
# differential_evolution step 226: f(x)= 147.54707783824222
# differential_evolution step 227: f(x)= 147.54707783824222
# differential_evolution step 228: f(x)= 147.54707783824222
# differential_evolution step 229: f(x)= 147.54707783824222
# differential_evolution step 230: f(x)= 147.54707783824222
# differential_evolution step 231: f(x)= 147.54707783824222
# differential_evolution step 232: f(x)= 147.54707783824222
# differential_evolution step 233: f(x)= 147.54707783824222
# differential_evolution step 234: f(x)= 147.54707783824222
# differential_evolution step 235: f(x)= 147.54707783824222
# differential_evolution step 236: f(x)= 147.54707783824222
# differential_evolution step 237: f(x)= 147.54707783824222
# differential_evolution step 238: f(x)= 147.5410235147089
# differential_evolution step 239: f(x)= 147.54052668231532
# differential_evolution step 240: f(x)= 147.5354204432196
# differential_evolution step 241: f(x)= 147.5354204432196
# differential_evolution step 242: f(x)= 147.5354204432196
# differential_evolution step 243: f(x)= 147.5354204432196
# differential_evolution step 244: f(x)= 147.5354204432196
# differential_evolution step 245: f(x)= 147.5354204432196
# differential_evolution step 246: f(x)= 147.5354204432196
# differential_evolution step 247: f(x)= 147.53511148258687
# differential_evolution step 248: f(x)= 147.53064587991318
# differential_evolution step 249: f(x)= 147.53064587991318
# differential_evolution step 250: f(x)= 147.53064587991318
# differential_evolution step 251: f(x)= 147.53064587991318
# differential_evolution step 252: f(x)= 147.53064587991318
# differential_evolution step 253: f(x)= 147.53064587991318
# differential_evolution step 254: f(x)= 147.53064587991318
# differential_evolution step 255: f(x)= 147.53064587991318
# differential_evolution step 256: f(x)= 147.53064587991318
# differential_evolution step 257: f(x)= 147.5231844799678
# differential_evolution step 258: f(x)= 147.5231844799678
# differential_evolution step 259: f(x)= 147.5231844799678
# differential_evolution step 260: f(x)= 147.5231844799678
# differential_evolution step 261: f(x)= 147.5231844799678
# differential_evolution step 262: f(x)= 147.5231844799678
# differential_evolution step 263: f(x)= 147.5231844799678
# differential_evolution step 264: f(x)= 147.5231844799678
# differential_evolution step 265: f(x)= 147.5231844799678
# differential_evolution step 266: f(x)= 147.52151863048
# differential_evolution step 267: f(x)= 147.52151863048
# differential_evolution step 268: f(x)= 147.52151863048
# differential_evolution step 269: f(x)= 147.52151863048
# differential_evolution step 270: f(x)= 147.52151863048
# differential_evolution step 271: f(x)= 147.52151863048
# differential_evolution step 272: f(x)= 147.52151863048
# differential_evolution step 273: f(x)= 147.52151863048
# differential_evolution step 274: f(x)= 147.52151863048
# differential_evolution step 275: f(x)= 147.52151863048
# differential_evolution step 276: f(x)= 147.52151863048
# differential_evolution step 277: f(x)= 147.52151863048
# differential_evolution step 278: f(x)= 147.52151863048
# differential_evolution step 279: f(x)= 147.52151863048
# differential_evolution step 280: f(x)= 147.52151863048
# differential_evolution step 281: f(x)= 147.52151863048
# differential_evolution step 282: f(x)= 147.52151863048
# differential_evolution step 283: f(x)= 147.52151863048
# differential_evolution step 284: f(x)= 147.52151863048
# differential_evolution step 285: f(x)= 147.5206701444786
# differential_evolution step 286: f(x)= 147.5206701444786
# differential_evolution step 287: f(x)= 147.5206701444786
# differential_evolution step 288: f(x)= 147.51901384099847
# differential_evolution step 289: f(x)= 147.51901384099847
# differential_evolution step 290: f(x)= 147.51901384099847
# differential_evolution step 291: f(x)= 147.51901384099847
# differential_evolution step 292: f(x)= 147.51901384099847
# differential_evolution step 293: f(x)= 147.51901384099847
# differential_evolution step 294: f(x)= 147.51901384099847
# differential_evolution step 295: f(x)= 147.51901384099847
# differential_evolution step 296: f(x)= 147.51888190058398
# differential_evolution step 297: f(x)= 147.51888190058398
# differential_evolution step 298: f(x)= 147.51888190058398
# differential_evolution step 299: f(x)= 147.51888190058398
# differential_evolution step 300: f(x)= 147.51834810704773
# differential_evolution step 301: f(x)= 147.51834810704773
# differential_evolution step 302: f(x)= 147.51824047448363
# differential_evolution step 303: f(x)= 147.51824047448363
# differential_evolution step 304: f(x)= 147.51824047448363
# differential_evolution step 305: f(x)= 147.518086153715
# differential_evolution step 306: f(x)= 147.518086153715
# differential_evolution step 307: f(x)= 147.518086153715
# differential_evolution step 308: f(x)= 147.51789603392544
# differential_evolution step 309: f(x)= 147.51789603392544
# differential_evolution step 310: f(x)= 147.51789603392544
# differential_evolution step 311: f(x)= 147.51771979680493
# differential_evolution step 312: f(x)= 147.51771979680493
# differential_evolution step 313: f(x)= 147.51771979680493
# differential_evolution step 314: f(x)= 147.51771979680493
# differential_evolution step 315: f(x)= 147.51740435362152
# differential_evolution step 316: f(x)= 147.51740435362152
# differential_evolution step 317: f(x)= 147.51735965084768
# differential_evolution step 318: f(x)= 147.51735965084768
# differential_evolution step 319: f(x)= 147.51735965084768
# differential_evolution step 320: f(x)= 147.51735965084768
# differential_evolution step 321: f(x)= 147.51735965084768
# differential_evolution step 322: f(x)= 147.51735965084768
# differential_evolution step 323: f(x)= 147.51730093199245
# differential_evolution step 324: f(x)= 147.51730093199245
# differential_evolution step 325: f(x)= 147.51730093199245
# differential_evolution step 326: f(x)= 147.51730093199245
# differential_evolution step 327: f(x)= 147.51692756744865
# differential_evolution step 328: f(x)= 147.51692756744865
# differential_evolution step 329: f(x)= 147.51596616562762
# differential_evolution step 330: f(x)= 147.51593739693345
# differential_evolution step 331: f(x)= 147.51593739693345
# differential_evolution step 332: f(x)= 147.51593739693345
# differential_evolution step 333: f(x)= 147.51593739693345
# differential_evolution step 334: f(x)= 147.51593739693345
# differential_evolution step 335: f(x)= 147.51575483467772
# differential_evolution step 336: f(x)= 147.51575483467772
# differential_evolution step 337: f(x)= 147.51575483467772
# differential_evolution step 338: f(x)= 147.51575483467772
# differential_evolution step 339: f(x)= 147.51575483467772
# differential_evolution step 340: f(x)= 147.51575483467772
# differential_evolution step 341: f(x)= 147.51541520991933
# differential_evolution step 342: f(x)= 147.51541520991933
# differential_evolution step 343: f(x)= 147.51541520991933
# differential_evolution step 344: f(x)= 147.51541520991933
# differential_evolution step 345: f(x)= 147.5153553271665
# differential_evolution step 346: f(x)= 147.5153553271665
# differential_evolution step 347: f(x)= 147.51534496943614
# differential_evolution step 348: f(x)= 147.51534496943614
# differential_evolution step 349: f(x)= 147.51534496943614
# differential_evolution step 350: f(x)= 147.51534496943614
# differential_evolution step 351: f(x)= 147.51534496943614
# differential_evolution step 352: f(x)= 147.51534496943614
# differential_evolution step 353: f(x)= 147.51534496943614
# differential_evolution step 354: f(x)= 147.51534496943614
# differential_evolution step 355: f(x)= 147.51534496943614
# differential_evolution step 356: f(x)= 147.51534496943614
# differential_evolution step 357: f(x)= 147.5152251933401
# differential_evolution step 358: f(x)= 147.51519052511503
# differential_evolution step 359: f(x)= 147.51519052511503
# differential_evolution step 360: f(x)= 147.51518679479227
# differential_evolution step 361: f(x)= 147.51518679479227
# differential_evolution step 362: f(x)= 147.51515269405033
# differential_evolution step 363: f(x)= 147.51515269405033
# differential_evolution step 364: f(x)= 147.51515269405033
# differential_evolution step 365: f(x)= 147.51515269405033
# differential_evolution step 366: f(x)= 147.51515269405033
# differential_evolution step 367: f(x)= 147.51515269405033
# differential_evolution step 368: f(x)= 147.51515269405033
# differential_evolution step 369: f(x)= 147.51515269405033
# differential_evolution step 370: f(x)= 147.51515269405033
# differential_evolution step 371: f(x)= 147.51509715438272
# differential_evolution step 372: f(x)= 147.51509715438272
# differential_evolution step 373: f(x)= 147.51509715438272
# differential_evolution step 374: f(x)= 147.51509715438272
# differential_evolution step 375: f(x)= 147.51509715438272
# differential_evolution step 376: f(x)= 147.51509715438272
# differential_evolution step 377: f(x)= 147.51509715438272
# differential_evolution step 378: f(x)= 147.51507225809715
# differential_evolution step 379: f(x)= 147.51504789283365
# differential_evolution step 380: f(x)= 147.51504789283365
# differential_evolution step 381: f(x)= 147.51504789283365
# differential_evolution step 382: f(x)= 147.51504789283365
# differential_evolution step 383: f(x)= 147.51504789283365
# differential_evolution step 384: f(x)= 147.51504789283365
# differential_evolution step 385: f(x)= 147.51504789283365
# differential_evolution step 386: f(x)= 147.51503887778617
# differential_evolution step 387: f(x)= 147.51503887778617
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=3.8976, x_0=39.8451
# Sérsic 2: I_e=0.1000, r_e=50.0000, n=2.4202, x_0=48.7750
# Sérsic 3: I_e=0.1000, r_e=10.1684, n=2.7451, x_0=57.4726
# Chi quadro minimo: 147.5149348452656
# True

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=3.8976, x_0=39.8451
# Sérsic 2: I_e=0.1000, r_e=50.0000, n=2.4202, x_0=48.7750
# Sérsic 3: I_e=0.1000, r_e=10.1684, n=2.7451, x_0=57.4726
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = real_errors_SII)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_9692\1087897001.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_9692\1087897001.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=7.4727, r_e=3.1565, n=0.6369, x_0=39.9557
# Sérsic 2: I_e=0.3055, r_e=19.9111, n=1.8539, x_0=48.3834
# Sérsic 3: I_e=0.8836, r_e=4.0902, n=1.0310, x_0=57.5603
# [0.24572331 0.05600399 0.02680349 0.04195344 0.05122814 1.68020931
#  0.12520474 0.08961789 0.10787154 0.35668427 0.09459162 0.07275295]
# 0.9287791802233522

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))

real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[1])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 257.95930863674215
# differential_evolution step 2: f(x)= 246.8626612643744
# differential_evolution step 3: f(x)= 240.6311746976442
# differential_evolution step 4: f(x)= 240.6311746976442
# differential_evolution step 5: f(x)= 240.6311746976442
# differential_evolution step 6: f(x)= 219.22077385090614
# differential_evolution step 7: f(x)= 167.60620986389705
# differential_evolution step 8: f(x)= 167.60620986389705
# differential_evolution step 9: f(x)= 167.60620986389705
# differential_evolution step 10: f(x)= 167.60620986389705
# differential_evolution step 11: f(x)= 134.45815566687153
# differential_evolution step 12: f(x)= 134.45815566687153
# differential_evolution step 13: f(x)= 134.45815566687153
# differential_evolution step 14: f(x)= 134.45815566687153
# differential_evolution step 15: f(x)= 121.19666401816731
# differential_evolution step 16: f(x)= 121.19666401816731
# differential_evolution step 17: f(x)= 98.10902049530844
# differential_evolution step 18: f(x)= 98.10902049530844
# differential_evolution step 19: f(x)= 98.10902049530844
# differential_evolution step 20: f(x)= 98.10902049530844
# differential_evolution step 21: f(x)= 94.92245350464613
# differential_evolution step 22: f(x)= 94.92245350464613
# differential_evolution step 23: f(x)= 94.92245350464613
# differential_evolution step 24: f(x)= 94.92245350464613
# differential_evolution step 25: f(x)= 94.92245350464613
# differential_evolution step 26: f(x)= 94.92245350464613
# differential_evolution step 27: f(x)= 94.92245350464613
# differential_evolution step 28: f(x)= 94.92245350464613
# differential_evolution step 29: f(x)= 94.92245350464613
# differential_evolution step 30: f(x)= 94.92245350464613
# differential_evolution step 31: f(x)= 94.92245350464613
# differential_evolution step 32: f(x)= 94.92245350464613
# differential_evolution step 33: f(x)= 94.92245350464613
# differential_evolution step 34: f(x)= 94.92245350464613
# differential_evolution step 35: f(x)= 94.92245350464613
# differential_evolution step 36: f(x)= 94.15554238960446
# differential_evolution step 37: f(x)= 94.15554238960446
# differential_evolution step 38: f(x)= 94.15554238960446
# differential_evolution step 39: f(x)= 94.15554238960446
# differential_evolution step 40: f(x)= 94.15554238960446
# differential_evolution step 41: f(x)= 89.53120929651993
# differential_evolution step 42: f(x)= 89.53120929651993
# differential_evolution step 43: f(x)= 89.53120929651993
# differential_evolution step 44: f(x)= 88.83933186485865
# differential_evolution step 45: f(x)= 88.27428942485277
# differential_evolution step 46: f(x)= 88.27428942485277
# differential_evolution step 47: f(x)= 85.99294560902455
# differential_evolution step 48: f(x)= 85.00815892449842
# differential_evolution step 49: f(x)= 85.00815892449842
# differential_evolution step 50: f(x)= 85.00815892449842
# differential_evolution step 51: f(x)= 84.0077147198181
# differential_evolution step 52: f(x)= 83.18256502473564
# differential_evolution step 53: f(x)= 82.56382528125988
# differential_evolution step 54: f(x)= 82.56382528125988
# differential_evolution step 55: f(x)= 81.04847921771082
# differential_evolution step 56: f(x)= 81.04847921771082
# differential_evolution step 57: f(x)= 81.04847921771082
# differential_evolution step 58: f(x)= 81.04847921771082
# differential_evolution step 59: f(x)= 81.04847921771082
# differential_evolution step 60: f(x)= 81.04847921771082
# differential_evolution step 61: f(x)= 80.77529597860226
# differential_evolution step 62: f(x)= 80.77529597860226
# differential_evolution step 63: f(x)= 80.55907528339462
# differential_evolution step 64: f(x)= 80.55907528339462
# differential_evolution step 65: f(x)= 80.55907528339462
# differential_evolution step 66: f(x)= 80.55907528339462
# differential_evolution step 67: f(x)= 80.55907528339462
# differential_evolution step 68: f(x)= 80.42107905374105
# differential_evolution step 69: f(x)= 80.42107905374105
# differential_evolution step 70: f(x)= 80.42107905374105
# differential_evolution step 71: f(x)= 80.42107905374105
# differential_evolution step 72: f(x)= 80.42107905374105
# differential_evolution step 73: f(x)= 79.98685625754634
# differential_evolution step 74: f(x)= 79.98685625754634
# differential_evolution step 75: f(x)= 79.98685625754634
# differential_evolution step 76: f(x)= 79.98685625754634
# differential_evolution step 77: f(x)= 79.98685625754634
# differential_evolution step 78: f(x)= 79.88417532980588
# differential_evolution step 79: f(x)= 79.88417532980588
# differential_evolution step 80: f(x)= 79.88417532980588
# differential_evolution step 81: f(x)= 79.88417532980588
# differential_evolution step 82: f(x)= 79.88417532980588
# differential_evolution step 83: f(x)= 79.88417532980588
# differential_evolution step 84: f(x)= 79.82187868733425
# differential_evolution step 85: f(x)= 79.82187868733425
# differential_evolution step 86: f(x)= 79.82187868733425
# differential_evolution step 87: f(x)= 79.82187868733425
# differential_evolution step 88: f(x)= 79.82187868733425
# differential_evolution step 89: f(x)= 79.82187868733425
# differential_evolution step 90: f(x)= 79.82187868733425
# differential_evolution step 91: f(x)= 79.82187868733425
# differential_evolution step 92: f(x)= 79.72688998266307
# differential_evolution step 93: f(x)= 79.72688998266307
# differential_evolution step 94: f(x)= 79.72688998266307
# differential_evolution step 95: f(x)= 79.72688998266307
# differential_evolution step 96: f(x)= 79.69708731293994
# differential_evolution step 97: f(x)= 79.48119858202045
# differential_evolution step 98: f(x)= 79.48119858202045
# differential_evolution step 99: f(x)= 79.48119858202045
# differential_evolution step 100: f(x)= 79.48119858202045
# differential_evolution step 101: f(x)= 79.45690411369098
# differential_evolution step 102: f(x)= 79.38177757182889
# differential_evolution step 103: f(x)= 79.38177757182889
# differential_evolution step 104: f(x)= 79.33535507920114
# differential_evolution step 105: f(x)= 79.33535507920114
# differential_evolution step 106: f(x)= 79.33535507920114
# differential_evolution step 107: f(x)= 79.33535507920114
# differential_evolution step 108: f(x)= 79.33535507920114
# differential_evolution step 109: f(x)= 79.33535507920114
# differential_evolution step 110: f(x)= 79.33535507920114
# differential_evolution step 111: f(x)= 79.33535507920114
# differential_evolution step 112: f(x)= 79.33535507920114
# differential_evolution step 113: f(x)= 79.33535507920114
# differential_evolution step 114: f(x)= 79.33535507920114
# differential_evolution step 115: f(x)= 79.33535507920114
# differential_evolution step 116: f(x)= 79.33535507920114
# differential_evolution step 117: f(x)= 79.28350386648314
# differential_evolution step 118: f(x)= 79.28350386648314
# differential_evolution step 119: f(x)= 79.21711614826069
# differential_evolution step 120: f(x)= 79.21711614826069
# differential_evolution step 121: f(x)= 79.21711614826069
# differential_evolution step 122: f(x)= 79.21711614826069
# differential_evolution step 123: f(x)= 79.21711614826069
# differential_evolution step 124: f(x)= 79.21711614826069
# differential_evolution step 125: f(x)= 79.21711614826069
# differential_evolution step 126: f(x)= 79.21711614826069
# differential_evolution step 127: f(x)= 79.21711614826069
# differential_evolution step 128: f(x)= 79.21711614826069
# differential_evolution step 129: f(x)= 79.21711614826069
# differential_evolution step 130: f(x)= 79.21711614826069
# differential_evolution step 131: f(x)= 79.21711614826069
# differential_evolution step 132: f(x)= 79.21711614826069
# differential_evolution step 133: f(x)= 79.1407991278656
# differential_evolution step 134: f(x)= 79.1407991278656
# differential_evolution step 135: f(x)= 79.1407991278656
# differential_evolution step 136: f(x)= 79.07587669617824
# differential_evolution step 137: f(x)= 79.07587669617824
# differential_evolution step 138: f(x)= 79.07587669617824
# differential_evolution step 139: f(x)= 79.0711166027585
# differential_evolution step 140: f(x)= 79.06729484831203
# differential_evolution step 141: f(x)= 79.00655485731833
# differential_evolution step 142: f(x)= 79.00655485731833
# differential_evolution step 143: f(x)= 79.00655485731833
# differential_evolution step 144: f(x)= 79.00655485731833
# differential_evolution step 145: f(x)= 78.98726507071925
# differential_evolution step 146: f(x)= 78.98726507071925
# differential_evolution step 147: f(x)= 78.98726507071925
# differential_evolution step 148: f(x)= 78.98279909469842
# differential_evolution step 149: f(x)= 78.97471394185911
# differential_evolution step 150: f(x)= 78.97471394185911
# differential_evolution step 151: f(x)= 78.97471394185911
# differential_evolution step 152: f(x)= 78.97471394185911
# differential_evolution step 153: f(x)= 78.97471394185911
# differential_evolution step 154: f(x)= 78.94269315540168
# differential_evolution step 155: f(x)= 78.94269315540168
# differential_evolution step 156: f(x)= 78.94269315540168
# differential_evolution step 157: f(x)= 78.94269315540168
# differential_evolution step 158: f(x)= 78.94269315540168
# differential_evolution step 159: f(x)= 78.94269315540168
# differential_evolution step 160: f(x)= 78.92340494685887
# differential_evolution step 161: f(x)= 78.91477593430557
# differential_evolution step 162: f(x)= 78.91477593430557
# differential_evolution step 163: f(x)= 78.90478817237361
# differential_evolution step 164: f(x)= 78.89313833624007
# differential_evolution step 165: f(x)= 78.89313833624007
# differential_evolution step 166: f(x)= 78.89313833624007
# differential_evolution step 167: f(x)= 78.88362102986974
# differential_evolution step 168: f(x)= 78.88362102986974
# differential_evolution step 169: f(x)= 78.88362102986974
# differential_evolution step 170: f(x)= 78.88362102986974
# differential_evolution step 171: f(x)= 78.88362102986974
# differential_evolution step 172: f(x)= 78.88362102986974
# differential_evolution step 173: f(x)= 78.88362102986974
# differential_evolution step 174: f(x)= 78.86308343470927
# differential_evolution step 175: f(x)= 78.86197059364808
# differential_evolution step 176: f(x)= 78.85972948044277
# differential_evolution step 177: f(x)= 78.85972948044277
# differential_evolution step 178: f(x)= 78.85972948044277
# differential_evolution step 179: f(x)= 78.85972948044277
# differential_evolution step 180: f(x)= 78.85972948044277
# differential_evolution step 181: f(x)= 78.85972948044277
# differential_evolution step 182: f(x)= 78.85972948044277
# differential_evolution step 183: f(x)= 78.85972948044277
# differential_evolution step 184: f(x)= 78.85972948044277
# differential_evolution step 185: f(x)= 78.85565725992396
# differential_evolution step 186: f(x)= 78.85565725992396
# differential_evolution step 187: f(x)= 78.84887793607272
# differential_evolution step 188: f(x)= 78.84113572384496
# differential_evolution step 189: f(x)= 78.83856239274986
# differential_evolution step 190: f(x)= 78.83856239274986
# differential_evolution step 191: f(x)= 78.83856239274986
# differential_evolution step 192: f(x)= 78.83856239274986
# differential_evolution step 193: f(x)= 78.83856239274986
# differential_evolution step 194: f(x)= 78.83728099186395
# differential_evolution step 195: f(x)= 78.83192329848161
# differential_evolution step 196: f(x)= 78.83192329848161
# differential_evolution step 197: f(x)= 78.83192329848161
# differential_evolution step 198: f(x)= 78.83192329848161
# differential_evolution step 199: f(x)= 78.8313325296039
# differential_evolution step 200: f(x)= 78.8313325296039
# differential_evolution step 201: f(x)= 78.82524782928078
# differential_evolution step 202: f(x)= 78.82524782928078
# differential_evolution step 203: f(x)= 78.82405611860632
# differential_evolution step 204: f(x)= 78.82405611860632
# differential_evolution step 205: f(x)= 78.82370402594832
# differential_evolution step 206: f(x)= 78.82370402594832
# differential_evolution step 207: f(x)= 78.81919880352115
# differential_evolution step 208: f(x)= 78.81919880352115
# differential_evolution step 209: f(x)= 78.81919880352115
# differential_evolution step 210: f(x)= 78.81919880352115
# differential_evolution step 211: f(x)= 78.81919880352115
# differential_evolution step 212: f(x)= 78.81089805418311
# differential_evolution step 213: f(x)= 78.81089805418311
# differential_evolution step 214: f(x)= 78.81089805418311
# differential_evolution step 215: f(x)= 78.81089805418311
# differential_evolution step 216: f(x)= 78.81089805418311
# differential_evolution step 217: f(x)= 78.81089805418311
# differential_evolution step 218: f(x)= 78.81089805418311
# differential_evolution step 219: f(x)= 78.81089805418311
# differential_evolution step 220: f(x)= 78.81089805418311
# differential_evolution step 221: f(x)= 78.81082085040441
# differential_evolution step 222: f(x)= 78.81082085040441
# differential_evolution step 223: f(x)= 78.81082085040441
# differential_evolution step 224: f(x)= 78.80800152944127
# differential_evolution step 225: f(x)= 78.8063200862287
# differential_evolution step 226: f(x)= 78.8034502611585
# differential_evolution step 227: f(x)= 78.8034502611585
# differential_evolution step 228: f(x)= 78.8034502611585
# differential_evolution step 229: f(x)= 78.80322167784509
# differential_evolution step 230: f(x)= 78.80295262819617
# differential_evolution step 231: f(x)= 78.80295262819617
# differential_evolution step 232: f(x)= 78.80295262819617
# differential_evolution step 233: f(x)= 78.80034770962277
# differential_evolution step 234: f(x)= 78.79967368626883
# differential_evolution step 235: f(x)= 78.79967368626883
# differential_evolution step 236: f(x)= 78.79967368626883
# differential_evolution step 237: f(x)= 78.79944073793193
# differential_evolution step 238: f(x)= 78.79939305389355
# differential_evolution step 239: f(x)= 78.79939305389355
# differential_evolution step 240: f(x)= 78.79939305389355
# differential_evolution step 241: f(x)= 78.79939305389355
# differential_evolution step 242: f(x)= 78.79939305389355
# differential_evolution step 243: f(x)= 78.79875812304874
# differential_evolution step 244: f(x)= 78.79875812304874
# differential_evolution step 245: f(x)= 78.79800478156707
# differential_evolution step 246: f(x)= 78.79800478156707
# differential_evolution step 247: f(x)= 78.79708827508168
# differential_evolution step 248: f(x)= 78.79708827508168
# differential_evolution step 249: f(x)= 78.79708827508168
# differential_evolution step 250: f(x)= 78.79708827508168
# differential_evolution step 251: f(x)= 78.79708827508168
# differential_evolution step 252: f(x)= 78.79708827508168
# differential_evolution step 253: f(x)= 78.79708827508168
# differential_evolution step 254: f(x)= 78.7968852581099
# differential_evolution step 255: f(x)= 78.7968852581099
# differential_evolution step 256: f(x)= 78.7968852581099
# differential_evolution step 257: f(x)= 78.7968852581099
# differential_evolution step 258: f(x)= 78.79587309616478
# differential_evolution step 259: f(x)= 78.79587309616478
# differential_evolution step 260: f(x)= 78.79585394854621
# differential_evolution step 261: f(x)= 78.79565896102056
# differential_evolution step 262: f(x)= 78.79565896102056
# differential_evolution step 263: f(x)= 78.79565896102056
# differential_evolution step 264: f(x)= 78.79565896102056
# differential_evolution step 265: f(x)= 78.79565896102056
# differential_evolution step 266: f(x)= 78.79565896102056
# differential_evolution step 267: f(x)= 78.79565896102056
# differential_evolution step 268: f(x)= 78.79565896102056
# differential_evolution step 269: f(x)= 78.79565896102056
# differential_evolution step 270: f(x)= 78.79565896102056
# differential_evolution step 271: f(x)= 78.79565896102056
# differential_evolution step 272: f(x)= 78.79487781067704
# differential_evolution step 273: f(x)= 78.79487781067704
# differential_evolution step 274: f(x)= 78.79487781067704
# differential_evolution step 275: f(x)= 78.79487781067704
# differential_evolution step 276: f(x)= 78.79487781067704
# differential_evolution step 277: f(x)= 78.79487781067704
# differential_evolution step 278: f(x)= 78.79487781067704
# differential_evolution step 279: f(x)= 78.79487781067704
# differential_evolution step 280: f(x)= 78.79487781067704
# differential_evolution step 281: f(x)= 78.79487781067704
# differential_evolution step 282: f(x)= 78.79487781067704
# differential_evolution step 283: f(x)= 78.79487351052039
# differential_evolution step 284: f(x)= 78.79487351052039
# differential_evolution step 285: f(x)= 78.79487351052039
# differential_evolution step 286: f(x)= 78.79487351052039
# differential_evolution step 287: f(x)= 78.79487351052039
# differential_evolution step 288: f(x)= 78.79487351052039
# differential_evolution step 289: f(x)= 78.79487351052039
# differential_evolution step 290: f(x)= 78.79487351052039
# differential_evolution step 291: f(x)= 78.79487351052039
# differential_evolution step 292: f(x)= 78.79470825391769
# differential_evolution step 293: f(x)= 78.79470825391769
# differential_evolution step 294: f(x)= 78.79464171075206
# differential_evolution step 295: f(x)= 78.79464171075206
# differential_evolution step 296: f(x)= 78.79464171075206
# differential_evolution step 297: f(x)= 78.79464171075206
# differential_evolution step 298: f(x)= 78.79464171075206
# differential_evolution step 299: f(x)= 78.79448333683801
# differential_evolution step 300: f(x)= 78.79448333683801
# differential_evolution step 301: f(x)= 78.79448333683801
# differential_evolution step 302: f(x)= 78.79442747091942
# differential_evolution step 303: f(x)= 78.79442747091942
# differential_evolution step 304: f(x)= 78.79442747091942
# differential_evolution step 305: f(x)= 78.79442747091942
# differential_evolution step 306: f(x)= 78.79442747091942
# differential_evolution step 307: f(x)= 78.79442747091942
# differential_evolution step 308: f(x)= 78.79442747091942
# differential_evolution step 309: f(x)= 78.79442747091942
# differential_evolution step 310: f(x)= 78.79442747091942
# differential_evolution step 311: f(x)= 78.79436180510442
# differential_evolution step 312: f(x)= 78.79436180510442
# differential_evolution step 313: f(x)= 78.79436180510442
# differential_evolution step 314: f(x)= 78.79436180510442
# differential_evolution step 315: f(x)= 78.79436180510442
# differential_evolution step 316: f(x)= 78.79436180510442
# differential_evolution step 317: f(x)= 78.79436180510442
# differential_evolution step 318: f(x)= 78.79436180510442
# differential_evolution step 319: f(x)= 78.79436180510442
# differential_evolution step 320: f(x)= 78.79436180510442
# differential_evolution step 321: f(x)= 78.79436180510442
# differential_evolution step 322: f(x)= 78.79436180510442
# differential_evolution step 323: f(x)= 78.79436180510442
# differential_evolution step 324: f(x)= 78.79436180510442
# differential_evolution step 325: f(x)= 78.79429582063375
# differential_evolution step 326: f(x)= 78.79429582063375
# differential_evolution step 327: f(x)= 78.79429582063375
# differential_evolution step 328: f(x)= 78.79429582063375
# differential_evolution step 329: f(x)= 78.79429582063375
# differential_evolution step 330: f(x)= 78.79429582063375
# differential_evolution step 331: f(x)= 78.79429582063375
# differential_evolution step 332: f(x)= 78.79429582063375
# differential_evolution step 333: f(x)= 78.79429088431596
# differential_evolution step 334: f(x)= 78.79427819106648
# differential_evolution step 335: f(x)= 78.79427819106648
# differential_evolution step 336: f(x)= 78.79427819106648
# differential_evolution step 337: f(x)= 78.79427819106648
# differential_evolution step 338: f(x)= 78.79427819106648
# differential_evolution step 339: f(x)= 78.79427819106648
# differential_evolution step 340: f(x)= 78.79427819106648
# differential_evolution step 341: f(x)= 78.79427819106648
# differential_evolution step 342: f(x)= 78.79424992410974
# differential_evolution step 343: f(x)= 78.79424992410974
# differential_evolution step 344: f(x)= 78.79424992410974
# differential_evolution step 345: f(x)= 78.79424992410974
# differential_evolution step 346: f(x)= 78.79423496083419
# differential_evolution step 347: f(x)= 78.79423496083419
# differential_evolution step 348: f(x)= 78.79423496083419
# differential_evolution step 349: f(x)= 78.79423496083419
# differential_evolution step 350: f(x)= 78.79419905568237
# differential_evolution step 351: f(x)= 78.79419630540471
# differential_evolution step 352: f(x)= 78.79419630540471
# differential_evolution step 353: f(x)= 78.79418266478997
# differential_evolution step 354: f(x)= 78.79418266478997
# differential_evolution step 355: f(x)= 78.79417676200032
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=4.0120, x_0=40.0925
# Sérsic 2: I_e=0.1000, r_e=42.8597, n=2.3182, x_0=48.7770
# Sérsic 3: I_e=0.1000, r_e=19.4982, n=2.8381, x_0=58.1217
# Chi quadro minimo: 78.79410947146262
# True

# %%
# Plots:
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=0.1000, r_e=50.0000, n=4.0120, x_0=40.0925
# Sérsic 2: I_e=0.1000, r_e=42.8597, n=2.3182, x_0=48.7770
# Sérsic 3: I_e=0.1000, r_e=19.4982, n=2.8381, x_0=58.1217
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = real_errors_OIII)#, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_9692\1087897001.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_9692\1087897001.py:22: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=6.8098, r_e=3.0679, n=0.7468, x_0=40.2378
# Sérsic 2: I_e=0.2836, r_e=26.1162, n=1.8156, x_0=49.2112
# Sérsic 3: I_e=0.8518, r_e=4.3777, n=1.2997, x_0=58.8544
# [0.32195857 0.08100342 0.04008247 0.04083566 0.05760719 2.87687936
#  0.14315003 0.11328299 0.16052482 0.59536205 0.14898114 0.06439877]
# 0.9144908820493172

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))

real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[0])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 19992.286459297047
# differential_evolution step 2: f(x)= 19992.286459297047
# differential_evolution step 3: f(x)= 19992.286459297047
# differential_evolution step 4: f(x)= 19132.74950406945
# differential_evolution step 5: f(x)= 19132.74950406945
# differential_evolution step 6: f(x)= 16554.572025538124
# differential_evolution step 7: f(x)= 16554.572025538124
# differential_evolution step 8: f(x)= 16554.572025538124
# differential_evolution step 9: f(x)= 16554.572025538124
# differential_evolution step 10: f(x)= 15855.365609435401
# differential_evolution step 11: f(x)= 15293.787170562931
# differential_evolution step 12: f(x)= 15293.787170562931
# differential_evolution step 13: f(x)= 11704.283735503237
# differential_evolution step 14: f(x)= 10462.543240146688
# differential_evolution step 15: f(x)= 10462.543240146688
# differential_evolution step 16: f(x)= 10462.543240146688
# differential_evolution step 17: f(x)= 10462.543240146688
# differential_evolution step 18: f(x)= 10462.543240146688
# differential_evolution step 19: f(x)= 10462.543240146688
# differential_evolution step 20: f(x)= 8914.588829855393
# differential_evolution step 21: f(x)= 8914.588829855393
# differential_evolution step 22: f(x)= 8914.588829855393
# differential_evolution step 23: f(x)= 8914.588829855393
# differential_evolution step 24: f(x)= 8914.588829855393
# differential_evolution step 25: f(x)= 8914.588829855393
# differential_evolution step 26: f(x)= 8914.588829855393
# differential_evolution step 27: f(x)= 8914.588829855393
# differential_evolution step 28: f(x)= 8914.588829855393
# differential_evolution step 29: f(x)= 8914.588829855393
# differential_evolution step 30: f(x)= 8914.588829855393
# differential_evolution step 31: f(x)= 8914.588829855393
# differential_evolution step 32: f(x)= 8914.588829855393
# differential_evolution step 33: f(x)= 8914.588829855393
# differential_evolution step 34: f(x)= 8818.663163909925
# differential_evolution step 35: f(x)= 8629.112611940218
# differential_evolution step 36: f(x)= 8629.112611940218
# differential_evolution step 37: f(x)= 8629.112611940218
# differential_evolution step 38: f(x)= 8629.112611940218
# differential_evolution step 39: f(x)= 8629.112611940218
# differential_evolution step 40: f(x)= 8558.05257095952
# differential_evolution step 41: f(x)= 8558.05257095952
# differential_evolution step 42: f(x)= 8558.05257095952
# differential_evolution step 43: f(x)= 8558.05257095952
# differential_evolution step 44: f(x)= 8558.05257095952
# differential_evolution step 45: f(x)= 8558.05257095952
# differential_evolution step 46: f(x)= 8558.05257095952
# differential_evolution step 47: f(x)= 8558.05257095952
# differential_evolution step 48: f(x)= 8558.05257095952
# differential_evolution step 49: f(x)= 8217.483613374558
# differential_evolution step 50: f(x)= 8217.483613374558
# differential_evolution step 51: f(x)= 8217.483613374558
# differential_evolution step 52: f(x)= 8217.483613374558
# differential_evolution step 53: f(x)= 8217.483613374558
# differential_evolution step 54: f(x)= 8217.483613374558
# differential_evolution step 55: f(x)= 8141.112395499833
# differential_evolution step 56: f(x)= 8141.112395499833
# differential_evolution step 57: f(x)= 8141.112395499833
# differential_evolution step 58: f(x)= 8141.112395499833
# differential_evolution step 59: f(x)= 8141.112395499833
# differential_evolution step 60: f(x)= 8141.112395499833
# differential_evolution step 61: f(x)= 8030.003071203041
# differential_evolution step 62: f(x)= 7909.406541731434
# differential_evolution step 63: f(x)= 7909.406541731434
# differential_evolution step 64: f(x)= 7909.406541731434
# differential_evolution step 65: f(x)= 7909.406541731434
# differential_evolution step 66: f(x)= 7830.189877486914
# differential_evolution step 67: f(x)= 7802.025276023715
# differential_evolution step 68: f(x)= 7781.447805505266
# differential_evolution step 69: f(x)= 7781.447805505266
# differential_evolution step 70: f(x)= 7303.945905191002
# differential_evolution step 71: f(x)= 7245.468463744865
# differential_evolution step 72: f(x)= 7245.468463744865
# differential_evolution step 73: f(x)= 7220.063059568955
# differential_evolution step 74: f(x)= 7220.063059568955
# differential_evolution step 75: f(x)= 7220.063059568955
# differential_evolution step 76: f(x)= 7207.979458242734
# differential_evolution step 77: f(x)= 7162.968327761708
# differential_evolution step 78: f(x)= 7079.36887797411
# differential_evolution step 79: f(x)= 7079.36887797411
# differential_evolution step 80: f(x)= 6987.616807538697
# differential_evolution step 81: f(x)= 6987.616807538697
# differential_evolution step 82: f(x)= 6969.010997065134
# differential_evolution step 83: f(x)= 6969.010997065134
# differential_evolution step 84: f(x)= 6930.637773618044
# differential_evolution step 85: f(x)= 6930.637773618044
# differential_evolution step 86: f(x)= 6684.057063862276
# differential_evolution step 87: f(x)= 6684.057063862276
# differential_evolution step 88: f(x)= 6684.057063862276
# differential_evolution step 89: f(x)= 6684.057063862276
# differential_evolution step 90: f(x)= 6684.057063862276
# differential_evolution step 91: f(x)= 6684.057063862276
# differential_evolution step 92: f(x)= 6684.057063862276
# differential_evolution step 93: f(x)= 6684.057063862276
# differential_evolution step 94: f(x)= 6569.580917224773
# differential_evolution step 95: f(x)= 6569.580917224773
# differential_evolution step 96: f(x)= 6569.580917224773
# differential_evolution step 97: f(x)= 6569.580917224773
# differential_evolution step 98: f(x)= 6569.580917224773
# differential_evolution step 99: f(x)= 6569.580917224773
# differential_evolution step 100: f(x)= 6569.580917224773
# differential_evolution step 101: f(x)= 6569.580917224773
# differential_evolution step 102: f(x)= 6569.580917224773
# differential_evolution step 103: f(x)= 6569.580917224773
# differential_evolution step 104: f(x)= 6569.580917224773
# differential_evolution step 105: f(x)= 6567.874247075074
# differential_evolution step 106: f(x)= 6567.874247075074
# differential_evolution step 107: f(x)= 6567.874247075074
# differential_evolution step 108: f(x)= 6567.874247075074
# differential_evolution step 109: f(x)= 6567.874247075074
# differential_evolution step 110: f(x)= 6555.487350314114
# differential_evolution step 111: f(x)= 6555.487350314114
# differential_evolution step 112: f(x)= 6555.487350314114
# differential_evolution step 113: f(x)= 6555.487350314114
# differential_evolution step 114: f(x)= 6555.487350314114
# differential_evolution step 115: f(x)= 6555.487350314114
# differential_evolution step 116: f(x)= 6555.487350314114
# differential_evolution step 117: f(x)= 6555.487350314114
# differential_evolution step 118: f(x)= 6555.487350314114
# differential_evolution step 119: f(x)= 6537.468488043522
# differential_evolution step 120: f(x)= 6537.468488043522
# differential_evolution step 121: f(x)= 6537.468488043522
# differential_evolution step 122: f(x)= 6537.468488043522
# differential_evolution step 123: f(x)= 6537.468488043522
# differential_evolution step 124: f(x)= 6537.468488043522
# differential_evolution step 125: f(x)= 6537.468488043522
# differential_evolution step 126: f(x)= 6529.565551413561
# differential_evolution step 127: f(x)= 6501.859362833109
# differential_evolution step 128: f(x)= 6501.859362833109
# differential_evolution step 129: f(x)= 6479.500009558469
# differential_evolution step 130: f(x)= 6479.500009558469
# differential_evolution step 131: f(x)= 6479.500009558469
# differential_evolution step 132: f(x)= 6470.292205135426
# differential_evolution step 133: f(x)= 6470.292205135426
# differential_evolution step 134: f(x)= 6470.292205135426
# differential_evolution step 135: f(x)= 6470.292205135426
# differential_evolution step 136: f(x)= 6470.292205135426
# differential_evolution step 137: f(x)= 6470.292205135426
# differential_evolution step 138: f(x)= 6470.292205135426
# differential_evolution step 139: f(x)= 6470.292205135426
# differential_evolution step 140: f(x)= 6470.292205135426
# differential_evolution step 141: f(x)= 6469.434422512621
# differential_evolution step 142: f(x)= 6469.434422512621
# differential_evolution step 143: f(x)= 6468.950086005987
# differential_evolution step 144: f(x)= 6463.128925509286
# differential_evolution step 145: f(x)= 6463.128925509286
# differential_evolution step 146: f(x)= 6462.362667188204
# differential_evolution step 147: f(x)= 6455.089772700338
# differential_evolution step 148: f(x)= 6455.089772700338
# differential_evolution step 149: f(x)= 6455.089772700338
# differential_evolution step 150: f(x)= 6455.089772700338
# differential_evolution step 151: f(x)= 6455.089772700338
# differential_evolution step 152: f(x)= 6455.089772700338
# differential_evolution step 153: f(x)= 6443.241576972697
# differential_evolution step 154: f(x)= 6443.241576972697
# differential_evolution step 155: f(x)= 6443.241576972697
# differential_evolution step 156: f(x)= 6443.241576972697
# differential_evolution step 157: f(x)= 6443.241576972697
# differential_evolution step 158: f(x)= 6442.134846294776
# differential_evolution step 159: f(x)= 6442.134846294776
# differential_evolution step 160: f(x)= 6442.134846294776
# differential_evolution step 161: f(x)= 6442.134846294776
# differential_evolution step 162: f(x)= 6442.134846294776
# differential_evolution step 163: f(x)= 6434.8616588094765
# differential_evolution step 164: f(x)= 6432.735685130147
# differential_evolution step 165: f(x)= 6432.735685130147
# differential_evolution step 166: f(x)= 6430.850407565021
# differential_evolution step 167: f(x)= 6428.307783882729
# differential_evolution step 168: f(x)= 6428.307783882729
# differential_evolution step 169: f(x)= 6427.647061219592
# differential_evolution step 170: f(x)= 6427.647061219592
# differential_evolution step 171: f(x)= 6427.647061219592
# differential_evolution step 172: f(x)= 6427.647061219592
# differential_evolution step 173: f(x)= 6427.647061219592
# differential_evolution step 174: f(x)= 6425.775804474947
# differential_evolution step 175: f(x)= 6425.775804474947
# differential_evolution step 176: f(x)= 6423.585728409794
# differential_evolution step 177: f(x)= 6422.747612241863
# differential_evolution step 178: f(x)= 6422.747612241863
# differential_evolution step 179: f(x)= 6414.602860392901
# differential_evolution step 180: f(x)= 6414.602860392901
# differential_evolution step 181: f(x)= 6414.602860392901
# differential_evolution step 182: f(x)= 6414.602860392901
# differential_evolution step 183: f(x)= 6414.602860392901
# differential_evolution step 184: f(x)= 6413.678839440726
# differential_evolution step 185: f(x)= 6413.678839440726
# differential_evolution step 186: f(x)= 6411.703314868223
# differential_evolution step 187: f(x)= 6407.004177322605
# differential_evolution step 188: f(x)= 6397.12181260274
# differential_evolution step 189: f(x)= 6397.12181260274
# differential_evolution step 190: f(x)= 6395.318461524924
# differential_evolution step 191: f(x)= 6395.318461524924
# differential_evolution step 192: f(x)= 6395.318461524924
# differential_evolution step 193: f(x)= 6395.318461524924
# differential_evolution step 194: f(x)= 6395.318461524924
# differential_evolution step 195: f(x)= 6395.318461524924
# differential_evolution step 196: f(x)= 6395.318461524924
# differential_evolution step 197: f(x)= 6395.318461524924
# differential_evolution step 198: f(x)= 6395.318461524924
# differential_evolution step 199: f(x)= 6395.318461524924
# differential_evolution step 200: f(x)= 6395.318461524924
# differential_evolution step 201: f(x)= 6395.318461524924
# differential_evolution step 202: f(x)= 6395.318461524924
# differential_evolution step 203: f(x)= 6395.318461524924
# differential_evolution step 204: f(x)= 6395.318461524924
# differential_evolution step 205: f(x)= 6395.017836810191
# differential_evolution step 206: f(x)= 6393.2968485310075
# differential_evolution step 207: f(x)= 6392.853482034656
# differential_evolution step 208: f(x)= 6388.623281046789
# differential_evolution step 209: f(x)= 6388.623281046789
# differential_evolution step 210: f(x)= 6388.623281046789
# differential_evolution step 211: f(x)= 6386.1805624070885
# differential_evolution step 212: f(x)= 6386.1805624070885
# differential_evolution step 213: f(x)= 6386.1805624070885
# differential_evolution step 214: f(x)= 6386.1805624070885
# differential_evolution step 215: f(x)= 6386.1805624070885
# differential_evolution step 216: f(x)= 6385.403887010768
# differential_evolution step 217: f(x)= 6385.403887010768
# differential_evolution step 218: f(x)= 6385.403887010768
# differential_evolution step 219: f(x)= 6385.403887010768
# differential_evolution step 220: f(x)= 6385.403887010768
# differential_evolution step 221: f(x)= 6384.754469672743
# differential_evolution step 222: f(x)= 6383.800588453219
# differential_evolution step 223: f(x)= 6383.800588453219
# differential_evolution step 224: f(x)= 6383.800588453219
# differential_evolution step 225: f(x)= 6382.0791483545
# differential_evolution step 226: f(x)= 6382.0791483545
# differential_evolution step 227: f(x)= 6382.0791483545
# differential_evolution step 228: f(x)= 6382.0791483545
# differential_evolution step 229: f(x)= 6380.655652072855
# differential_evolution step 230: f(x)= 6380.264541773307
# differential_evolution step 231: f(x)= 6379.048846335599
# differential_evolution step 232: f(x)= 6379.048846335599
# differential_evolution step 233: f(x)= 6376.91130246378
# differential_evolution step 234: f(x)= 6370.081624493169
# differential_evolution step 235: f(x)= 6370.081624493169
# differential_evolution step 236: f(x)= 6370.081624493169
# differential_evolution step 237: f(x)= 6369.37276280885
# differential_evolution step 238: f(x)= 6369.37276280885
# differential_evolution step 239: f(x)= 6369.37276280885
# differential_evolution step 240: f(x)= 6369.37276280885
# differential_evolution step 241: f(x)= 6369.37276280885
# differential_evolution step 242: f(x)= 6369.37276280885
# differential_evolution step 243: f(x)= 6367.774344032211
# differential_evolution step 244: f(x)= 6367.774344032211
# differential_evolution step 245: f(x)= 6367.774344032211
# differential_evolution step 246: f(x)= 6367.774344032211
# differential_evolution step 247: f(x)= 6367.497866014203
# differential_evolution step 248: f(x)= 6367.497866014203
# differential_evolution step 249: f(x)= 6366.798461809436
# differential_evolution step 250: f(x)= 6366.536942986223
# differential_evolution step 251: f(x)= 6366.041993191766
# differential_evolution step 252: f(x)= 6366.041993191766
# differential_evolution step 253: f(x)= 6365.1656959863885
# differential_evolution step 254: f(x)= 6365.1656959863885
# differential_evolution step 255: f(x)= 6365.1656959863885
# differential_evolution step 256: f(x)= 6364.701378637042
# differential_evolution step 257: f(x)= 6364.701378637042
# differential_evolution step 258: f(x)= 6364.404589502012
# differential_evolution step 259: f(x)= 6363.3958347766475
# differential_evolution step 260: f(x)= 6363.3958347766475
# differential_evolution step 261: f(x)= 6363.3958347766475
# differential_evolution step 262: f(x)= 6363.3958347766475
# differential_evolution step 263: f(x)= 6363.246933243031
# differential_evolution step 264: f(x)= 6363.246933243031
# differential_evolution step 265: f(x)= 6363.246933243031
# differential_evolution step 266: f(x)= 6363.246933243031
# differential_evolution step 267: f(x)= 6363.246933243031
# differential_evolution step 268: f(x)= 6363.246933243031
# differential_evolution step 269: f(x)= 6363.246933243031
# differential_evolution step 270: f(x)= 6363.246933243031
# differential_evolution step 271: f(x)= 6363.246933243031
# differential_evolution step 272: f(x)= 6363.246933243031
# differential_evolution step 273: f(x)= 6363.246933243031
# differential_evolution step 274: f(x)= 6363.246933243031
# differential_evolution step 275: f(x)= 6363.246933243031
# differential_evolution step 276: f(x)= 6363.246933243031
# differential_evolution step 277: f(x)= 6363.246933243031
# differential_evolution step 278: f(x)= 6363.246933243031
# differential_evolution step 279: f(x)= 6363.246933243031
# differential_evolution step 280: f(x)= 6363.246933243031
# differential_evolution step 281: f(x)= 6363.246933243031
# differential_evolution step 282: f(x)= 6363.246933243031
# differential_evolution step 283: f(x)= 6363.246933243031
# differential_evolution step 284: f(x)= 6363.246933243031
# differential_evolution step 285: f(x)= 6363.246933243031
# differential_evolution step 286: f(x)= 6363.246933243031
# differential_evolution step 287: f(x)= 6363.246933243031
# differential_evolution step 288: f(x)= 6363.246933243031
# differential_evolution step 289: f(x)= 6362.90793009112
# differential_evolution step 290: f(x)= 6362.45731741939
# differential_evolution step 291: f(x)= 6362.45731741939
# differential_evolution step 292: f(x)= 6362.45731741939
# differential_evolution step 293: f(x)= 6362.45731741939
# differential_evolution step 294: f(x)= 6362.168301129495
# differential_evolution step 295: f(x)= 6362.168301129495
# differential_evolution step 296: f(x)= 6362.168301129495
# differential_evolution step 297: f(x)= 6362.168301129495
# differential_evolution step 298: f(x)= 6362.168301129495
# differential_evolution step 299: f(x)= 6362.168301129495
# differential_evolution step 300: f(x)= 6362.168301129495
# differential_evolution step 301: f(x)= 6362.168301129495
# differential_evolution step 302: f(x)= 6362.168301129495
# differential_evolution step 303: f(x)= 6362.168301129495
# differential_evolution step 304: f(x)= 6362.168301129495
# differential_evolution step 305: f(x)= 6362.168049579048
# differential_evolution step 306: f(x)= 6361.979520488803
# differential_evolution step 307: f(x)= 6361.979520488803
# differential_evolution step 308: f(x)= 6361.979520488803
# differential_evolution step 309: f(x)= 6361.979520488803
# differential_evolution step 310: f(x)= 6361.979520488803
# differential_evolution step 311: f(x)= 6361.979520488803
# differential_evolution step 312: f(x)= 6361.979520488803
# differential_evolution step 313: f(x)= 6361.979520488803
# differential_evolution step 314: f(x)= 6361.979520488803
# differential_evolution step 315: f(x)= 6361.979520488803
# differential_evolution step 316: f(x)= 6361.979520488803
# differential_evolution step 317: f(x)= 6361.979520488803
# differential_evolution step 318: f(x)= 6361.979520488803
# differential_evolution step 319: f(x)= 6361.979520488803
# differential_evolution step 320: f(x)= 6361.979520488803
# differential_evolution step 321: f(x)= 6361.979520488803
# differential_evolution step 322: f(x)= 6361.743842394526
# differential_evolution step 323: f(x)= 6361.743842394526
# differential_evolution step 324: f(x)= 6361.743842394526
# differential_evolution step 325: f(x)= 6361.743842394526
# differential_evolution step 326: f(x)= 6361.743842394526
# differential_evolution step 327: f(x)= 6361.743842394526
# differential_evolution step 328: f(x)= 6361.743842394526
# differential_evolution step 329: f(x)= 6361.743842394526
# differential_evolution step 330: f(x)= 6361.743842394526
# differential_evolution step 331: f(x)= 6361.743842394526
# differential_evolution step 332: f(x)= 6361.718355829734
# differential_evolution step 333: f(x)= 6361.718355829734
# differential_evolution step 334: f(x)= 6361.718355829734
# differential_evolution step 335: f(x)= 6361.718355829734
# differential_evolution step 336: f(x)= 6361.718355829734
# differential_evolution step 337: f(x)= 6361.685814079591
# differential_evolution step 338: f(x)= 6361.685814079591
# differential_evolution step 339: f(x)= 6361.685814079591
# differential_evolution step 340: f(x)= 6361.685814079591
# differential_evolution step 341: f(x)= 6361.685814079591
# differential_evolution step 342: f(x)= 6361.685814079591
# differential_evolution step 343: f(x)= 6361.685814079591
# differential_evolution step 344: f(x)= 6361.685814079591
# differential_evolution step 345: f(x)= 6361.685814079591
# differential_evolution step 346: f(x)= 6361.685814079591
# differential_evolution step 347: f(x)= 6361.685814079591
# differential_evolution step 348: f(x)= 6361.653609982665
# differential_evolution step 349: f(x)= 6361.653609982665
# differential_evolution step 350: f(x)= 6361.653609982665
# differential_evolution step 351: f(x)= 6361.653609982665
# differential_evolution step 352: f(x)= 6361.653609982665
# differential_evolution step 353: f(x)= 6361.6346954747
# differential_evolution step 354: f(x)= 6361.6346954747
# differential_evolution step 355: f(x)= 6361.6346954747
# differential_evolution step 356: f(x)= 6361.6346954747
# differential_evolution step 357: f(x)= 6361.6346954747
# differential_evolution step 358: f(x)= 6361.6346954747
# differential_evolution step 359: f(x)= 6361.6346954747
# differential_evolution step 360: f(x)= 6361.632207520023
# differential_evolution step 361: f(x)= 6361.632207520023
# differential_evolution step 362: f(x)= 6361.632207520023
# differential_evolution step 363: f(x)= 6361.632207520023
# differential_evolution step 364: f(x)= 6361.618144149151
# differential_evolution step 365: f(x)= 6361.608515979316
# differential_evolution step 366: f(x)= 6361.608515979316
# differential_evolution step 367: f(x)= 6361.608515979316
# differential_evolution step 368: f(x)= 6361.608515979316
# differential_evolution step 369: f(x)= 6361.608515979316
# differential_evolution step 370: f(x)= 6361.608515979316
# differential_evolution step 371: f(x)= 6361.590270114739
# differential_evolution step 372: f(x)= 6361.590270114739
# differential_evolution step 373: f(x)= 6361.590270114739
# differential_evolution step 374: f(x)= 6361.579983170464
# differential_evolution step 375: f(x)= 6361.579983170464
# differential_evolution step 376: f(x)= 6361.579983170464
# differential_evolution step 377: f(x)= 6361.579983170464
# differential_evolution step 378: f(x)= 6361.579983170464
# differential_evolution step 379: f(x)= 6361.579983170464
# differential_evolution step 380: f(x)= 6361.579983170464
# differential_evolution step 381: f(x)= 6361.579983170464
# differential_evolution step 382: f(x)= 6361.5791765695185
# differential_evolution step 383: f(x)= 6361.5791765695185
# differential_evolution step 384: f(x)= 6361.563455288019
# differential_evolution step 385: f(x)= 6361.563455288019
# differential_evolution step 386: f(x)= 6361.563455288019
# differential_evolution step 387: f(x)= 6361.563455288019
# differential_evolution step 388: f(x)= 6361.5615204677015
# differential_evolution step 389: f(x)= 6361.561229810653
# differential_evolution step 390: f(x)= 6361.561229810653
# differential_evolution step 391: f(x)= 6361.5586277992
# differential_evolution step 392: f(x)= 6361.5586277992
# differential_evolution step 393: f(x)= 6361.5586277992
# differential_evolution step 394: f(x)= 6361.5586277992
# differential_evolution step 395: f(x)= 6361.557197509558
# differential_evolution step 396: f(x)= 6361.555877278859
# differential_evolution step 397: f(x)= 6361.555877278859
# differential_evolution step 398: f(x)= 6361.555877278859
# differential_evolution step 399: f(x)= 6361.555877278859
# differential_evolution step 400: f(x)= 6361.555877278859
# differential_evolution step 401: f(x)= 6361.555877278859
# differential_evolution step 402: f(x)= 6361.555877278859
# differential_evolution step 403: f(x)= 6361.555877278859
# differential_evolution step 404: f(x)= 6361.555877278859
# differential_evolution step 405: f(x)= 6361.555877278859
# differential_evolution step 406: f(x)= 6361.555877278859
# differential_evolution step 407: f(x)= 6361.555180828833
# differential_evolution step 408: f(x)= 6361.555180828833
# differential_evolution step 409: f(x)= 6361.553452778825
# differential_evolution step 410: f(x)= 6361.552608858062
# differential_evolution step 411: f(x)= 6361.552608858062
# differential_evolution step 412: f(x)= 6361.552608858062
# differential_evolution step 413: f(x)= 6361.552608858062
# differential_evolution step 414: f(x)= 6361.552608858062
# differential_evolution step 415: f(x)= 6361.552608858062
# differential_evolution step 416: f(x)= 6361.551497177516
# differential_evolution step 417: f(x)= 6361.550589941177
# differential_evolution step 418: f(x)= 6361.548559392332
# differential_evolution step 419: f(x)= 6361.548559392332
# differential_evolution step 420: f(x)= 6361.548559392332
# differential_evolution step 421: f(x)= 6361.548559392332
# differential_evolution step 422: f(x)= 6361.548559392332
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=10.0000, r_e=11.6135, n=1.8818, x_0=40.5877
# Sérsic 2: I_e=10.0000, r_e=7.8844, n=0.7978, x_0=46.0000
# Sérsic 3: I_e=4.2916, r_e=5.6071, n=1.9762, x_0=59.0484
# Chi quadro minimo: 6361.544207253237
# True

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20]), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24]), color = 'purple', linestyle='--', label='Sérsic 6')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 15)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Sérsic 1: I_e=10.0000, r_e=11.6135, n=1.8818, x_0=40.5877
# Sérsic 2: I_e=10.0000, r_e=7.8844, n=0.7978, x_0=46.0000
# Sérsic 3: I_e=4.2916, r_e=5.6071, n=1.9762, x_0=59.0484
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=9.9460, r_e=5.5124, n=2.3770, x_0=40.5083
# Sérsic 2: I_e=9.9997, r_e=7.1190, n=1.0371, x_0=47.7478
# Sérsic 3: I_e=7.1876, r_e=4.7857, n=1.5081, x_0=59.0188
# [14.80816006  6.2148834   1.20153194  0.2408382  11.69480181  8.6211868
#   0.82040073  0.70515749  4.59089104  3.00498372  0.59549276  0.2573483 ]
# 29.939336281474517

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))

real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA
seeing_i = 3.174
sigma_i = seeing_i/ 2.35

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigma_i)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 89291.22364274372
# differential_evolution step 2: f(x)= 34332.2494595456
# differential_evolution step 3: f(x)= 34332.2494595456
# differential_evolution step 4: f(x)= 34332.2494595456
# differential_evolution step 5: f(x)= 34332.2494595456
# differential_evolution step 6: f(x)= 34332.2494595456
# differential_evolution step 7: f(x)= 34332.2494595456
# differential_evolution step 8: f(x)= 26380.953281791408
# differential_evolution step 9: f(x)= 26380.953281791408
# differential_evolution step 10: f(x)= 26380.953281791408
# differential_evolution step 11: f(x)= 25321.605194847914
# differential_evolution step 12: f(x)= 22146.719776015565
# differential_evolution step 13: f(x)= 20815.5855955456
# differential_evolution step 14: f(x)= 20815.5855955456
# differential_evolution step 15: f(x)= 20815.5855955456
# differential_evolution step 16: f(x)= 18696.966448777464
# differential_evolution step 17: f(x)= 18696.966448777464
# differential_evolution step 18: f(x)= 16048.749327479138
# differential_evolution step 19: f(x)= 16048.749327479138
# differential_evolution step 20: f(x)= 16048.749327479138
# differential_evolution step 21: f(x)= 16048.749327479138
# differential_evolution step 22: f(x)= 16048.749327479138
# differential_evolution step 23: f(x)= 16048.749327479138
# differential_evolution step 24: f(x)= 16048.749327479138
# differential_evolution step 25: f(x)= 16048.749327479138
# differential_evolution step 26: f(x)= 16048.749327479138
# differential_evolution step 27: f(x)= 16048.749327479138

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigma_i,
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')

# %%
bounds = bounds_HA
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigma_i, *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigma_i, x_axes, n_component, line_name="Continuum_2", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigma_i, r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6000)*(wv < 6500)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))

real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')

# %%
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')

# %%
d1 = {'Name': ['Continuum 3'], 'Chi squared': chi2_continuum_3,
      'Dof': dof_continuum_3, 'Chi reduced': chi2_reduced_continuum_3}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_continuum_3.csv", index= False)

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII, 
           chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII, 
           dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII, 
           chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII', 'Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)
