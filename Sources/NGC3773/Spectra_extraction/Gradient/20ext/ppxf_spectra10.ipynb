# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_10.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00328   
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
error_rf = error[wv_mask]*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4437.14616059 4438.62132206 4440.09648353 ... 7070.30938522 7071.78454669
#  7073.25970816] [2.46449135 2.41067218 2.498504   ... 1.29290755 1.29372071 1.30460601] [0.05186692 0.05134512 0.05207169 ... 0.02332209 0.02338657 0.02342226]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21857308 2.21931066 2.22004824 ... 3.53515469 3.53589227 3.53662985]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
# chi2/DOF: 0.0006235; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
# chi2/DOF: 0.0003702; DOF: 1894; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-59.44868217,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -64        32
#  comp.  2:       -66        45
# chi2/DOF: 4.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.15     0.081     -64    32
# Comp:  1                Halpha      35.28     0.096     -64    32
# Comp:  2             [SII]6716      5.231     0.045     -66    45
# Comp:  2             [SII]6731      3.923     0.041     -66    45
# Comp:  2              HeII4687     0.1475     0.048     -66    45
# Comp:  2               HeI5876      1.390     0.038     -66    45
# Comp:  2          [OIII]5007_d      31.64      0.12     -66    45
# Comp:  2            [OI]6300_d     0.6751     0.040     -66    45
# Comp:  2           [NII]6583_d      8.762     0.060     -66    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  253.3; gas flux:     15 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  585.2; gas flux:     48 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:     79; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  60.37; gas flux:      6 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.142; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  19.89; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  350.1; gas flux:     33 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.791; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  100.9; gas flux:     12 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        35
#  comp.  1:       -63        33
#  comp.  2:       -63        46
# chi2/DOF: 3.930; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.76     0.081     -63    33
# Comp:  1                Halpha      34.49     0.096     -63    33
# Comp:  2             [SII]6716      5.241     0.045     -63    46
# Comp:  2             [SII]6731      4.143     0.041     -63    46
# Comp:  2              HeII4687     0.1839     0.048     -63    46
# Comp:  2               HeI5876      1.545     0.039     -63    46
# Comp:  2          [OIII]5007_d      31.91      0.12     -63    46
# Comp:  2            [OI]6300_d     0.6317     0.040     -63    46
# Comp:  2           [NII]6583_d      9.530     0.060     -63    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -58        37
#  comp.  2:       -66        48
# chi2/DOF: 3.364; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.95     0.082     -58    37
# Comp:  1                Halpha      37.22     0.096     -58    37
# Comp:  2             [SII]6716      5.198     0.045     -66    48
# Comp:  2             [SII]6731      4.109     0.042     -66    48
# Comp:  2              HeII4687     0.1933     0.049     -66    48
# Comp:  2               HeI5876      1.491     0.039     -66    48
# Comp:  2          [OIII]5007_d      32.20      0.12     -66    48
# Comp:  2            [OI]6300_d     0.7560     0.040     -66    48
# Comp:  2           [NII]6583_d      9.883     0.061     -66    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -67        28
#  comp.  2:       -64        49
# chi2/DOF: 3.840; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.98     0.080     -67    28
# Comp:  1                Halpha      34.22     0.096     -67    28
# Comp:  2             [SII]6716      5.340     0.045     -64    49
# Comp:  2             [SII]6731      3.821     0.042     -64    49
# Comp:  2              HeII4687     0.1811     0.049     -64    49
# Comp:  2               HeI5876      1.444     0.039     -64    49
# Comp:  2          [OIII]5007_d      32.70      0.12     -64    49
# Comp:  2            [OI]6300_d     0.7078     0.041     -64    49
# Comp:  2           [NII]6583_d      9.080     0.061     -64    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        19
#  comp.  1:       -58        40
#  comp.  2:       -65        44
# chi2/DOF: 3.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.53     0.083     -58    40
# Comp:  1                Halpha      36.85     0.096     -58    40
# Comp:  2             [SII]6716      5.172     0.045     -65    44
# Comp:  2             [SII]6731      3.539     0.041     -65    44
# Comp:  2              HeII4687    0.09322     0.048     -65    44
# Comp:  2               HeI5876      1.409     0.038     -65    44
# Comp:  2          [OIII]5007_d      32.14      0.12     -65    44
# Comp:  2            [OI]6300_d     0.6683     0.040     -65    44
# Comp:  2           [NII]6583_d      8.098     0.060     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        30
#  comp.  1:       -66        34
#  comp.  2:       -65        46
# chi2/DOF: 4.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.72     0.081     -66    34
# Comp:  1                Halpha      35.29     0.096     -66    34
# Comp:  2             [SII]6716      5.284     0.045     -65    46
# Comp:  2             [SII]6731      3.651     0.041     -65    46
# Comp:  2              HeII4687     0.1385     0.048     -65    46
# Comp:  2               HeI5876      1.482     0.039     -65    46
# Comp:  2          [OIII]5007_d      31.21      0.12     -65    46
# Comp:  2            [OI]6300_d     0.6620     0.040     -65    46
# Comp:  2           [NII]6583_d      8.588     0.060     -65    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -65        28
#  comp.  2:       -65        41
# chi2/DOF: 4.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.87     0.080     -65    28
# Comp:  1                Halpha      35.29     0.096     -65    28
# Comp:  2             [SII]6716      5.229     0.044     -65    41
# Comp:  2             [SII]6731      3.633     0.041     -65    41
# Comp:  2              HeII4687     0.1238     0.048     -65    41
# Comp:  2               HeI5876      1.329     0.038     -65    41
# Comp:  2          [OIII]5007_d      31.11      0.12     -65    41
# Comp:  2            [OI]6300_d     0.6477     0.040     -65    41
# Comp:  2           [NII]6583_d      9.178     0.060     -65    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -58        36
#  comp.  2:       -68        44
# chi2/DOF: 3.654; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.27     0.082     -58    36
# Comp:  1                Halpha      36.43     0.096     -58    36
# Comp:  2             [SII]6716      5.191     0.045     -68    44
# Comp:  2             [SII]6731      3.952     0.041     -68    44
# Comp:  2              HeII4687     0.1312     0.048     -68    44
# Comp:  2               HeI5876      1.356     0.038     -68    44
# Comp:  2          [OIII]5007_d      31.43      0.12     -68    44
# Comp:  2            [OI]6300_d     0.6952     0.040     -68    44
# Comp:  2           [NII]6583_d      8.553     0.060     -68    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -69        28
#  comp.  2:       -66        41
# chi2/DOF: 3.570; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74     0.080     -69    28
# Comp:  1                Halpha      33.13     0.096     -69    28
# Comp:  2             [SII]6716      5.201     0.044     -66    41
# Comp:  2             [SII]6731      3.911     0.041     -66    41
# Comp:  2              HeII4687     0.1749     0.048     -66    41
# Comp:  2               HeI5876      1.338     0.038     -66    41
# Comp:  2          [OIII]5007_d      30.86      0.12     -66    41
# Comp:  2            [OI]6300_d     0.7295     0.040     -66    41
# Comp:  2           [NII]6583_d      8.873     0.060     -66    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        32
#  comp.  1:       -68        22
#  comp.  2:       -67        42
# chi2/DOF: 3.329; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.32     0.079     -68    22
# Comp:  1                Halpha      32.97     0.095     -68    22
# Comp:  2             [SII]6716      5.054     0.045     -67    42
# Comp:  2             [SII]6731      4.104     0.041     -67    42
# Comp:  2              HeII4687     0.1931     0.048     -67    42
# Comp:  2               HeI5876      1.436     0.038     -67    42
# Comp:  2          [OIII]5007_d      30.96      0.12     -67    42
# Comp:  2            [OI]6300_d     0.6804     0.040     -67    42
# Comp:  2           [NII]6583_d      8.881     0.060     -67    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -66        29
#  comp.  2:       -67        43
# chi2/DOF: 3.978; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.85     0.081     -66    29
# Comp:  1                Halpha      36.24     0.096     -66    29
# Comp:  2             [SII]6716      5.130     0.045     -67    43
# Comp:  2             [SII]6731      3.673     0.041     -67    43
# Comp:  2              HeII4687     0.1217     0.048     -67    43
# Comp:  2               HeI5876      1.394     0.038     -67    43
# Comp:  2          [OIII]5007_d      31.27      0.12     -67    43
# Comp:  2            [OI]6300_d     0.7375     0.040     -67    43
# Comp:  2           [NII]6583_d      9.102     0.060     -67    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        21
#  comp.  1:       -63        39
#  comp.  2:       -68        46
# chi2/DOF: 3.965; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.02     0.082     -63    39
# Comp:  1                Halpha      35.90     0.097     -63    39
# Comp:  2             [SII]6716      5.172     0.045     -68    46
# Comp:  2             [SII]6731      3.917     0.042     -68    46
# Comp:  2              HeII4687    0.09712     0.048     -68    46
# Comp:  2               HeI5876      1.432     0.039     -68    46
# Comp:  2          [OIII]5007_d      31.80      0.12     -68    46
# Comp:  2            [OI]6300_d     0.7058     0.040     -68    46
# Comp:  2           [NII]6583_d      8.695     0.060     -68    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -66        25
#  comp.  2:       -67        48
# chi2/DOF: 3.688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.97     0.080     -66    25
# Comp:  1                Halpha      33.38     0.096     -66    25
# Comp:  2             [SII]6716      5.386     0.045     -67    48
# Comp:  2             [SII]6731      4.227     0.042     -67    48
# Comp:  2              HeII4687     0.2077     0.049     -67    48
# Comp:  2               HeI5876      1.456     0.039     -67    48
# Comp:  2          [OIII]5007_d      31.74      0.12     -67    48
# Comp:  2            [OI]6300_d     0.6966     0.040     -67    48
# Comp:  2           [NII]6583_d      8.273     0.061     -67    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        12
#  comp.  1:       -66        25
#  comp.  2:       -65        40
# chi2/DOF: 3.721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.87     0.080     -66    25
# Comp:  1                Halpha      33.29     0.096     -66    25
# Comp:  2             [SII]6716      5.091     0.044     -65    40
# Comp:  2             [SII]6731      3.753     0.041     -65    40
# Comp:  2              HeII4687     0.1401     0.047     -65    40
# Comp:  2               HeI5876      1.399     0.038     -65    40
# Comp:  2          [OIII]5007_d      31.54      0.12     -65    40
# Comp:  2            [OI]6300_d     0.6888     0.040     -65    40
# Comp:  2           [NII]6583_d      8.541     0.060     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        39
#  comp.  1:       -60        33
#  comp.  2:       -71        44
# chi2/DOF: 3.512; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.75     0.081     -60    33
# Comp:  1                Halpha      37.11     0.096     -60    33
# Comp:  2             [SII]6716      5.233     0.045     -71    44
# Comp:  2             [SII]6731      3.912     0.041     -71    44
# Comp:  2              HeII4687     0.1147     0.048     -71    44
# Comp:  2               HeI5876      1.370     0.038     -71    44
# Comp:  2          [OIII]5007_d      31.44      0.12     -71    44
# Comp:  2            [OI]6300_d     0.6329     0.040     -71    44
# Comp:  2           [NII]6583_d      9.055     0.060     -71    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        41
#  comp.  1:       -60        33
#  comp.  2:       -64        44
# chi2/DOF: 3.824; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.85     0.081     -60    33
# Comp:  1                Halpha      36.83     0.096     -60    33
# Comp:  2             [SII]6716      5.170     0.045     -64    44
# Comp:  2             [SII]6731      4.053     0.041     -64    44
# Comp:  2              HeII4687     0.1255     0.048     -64    44
# Comp:  2               HeI5876      1.496     0.038     -64    44
# Comp:  2          [OIII]5007_d      31.76      0.12     -64    44
# Comp:  2            [OI]6300_d     0.5783     0.040     -64    44
# Comp:  2           [NII]6583_d      8.721     0.060     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -65        29
#  comp.  2:       -66        48
# chi2/DOF: 4.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.99     0.081     -65    29
# Comp:  1                Halpha      35.84     0.096     -65    29
# Comp:  2             [SII]6716      5.258     0.045     -66    48
# Comp:  2             [SII]6731      3.996     0.042     -66    48
# Comp:  2              HeII4687     0.1661     0.049     -66    48
# Comp:  2               HeI5876      1.325     0.039     -66    48
# Comp:  2          [OIII]5007_d      32.45      0.12     -66    48
# Comp:  2            [OI]6300_d     0.6514     0.040     -66    48
# Comp:  2           [NII]6583_d      9.016     0.061     -66    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -63        39
#  comp.  2:       -67        47
# chi2/DOF: 3.969; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.48     0.082     -63    39
# Comp:  1                Halpha      35.02     0.097     -63    39
# Comp:  2             [SII]6716      5.289     0.045     -67    47
# Comp:  2             [SII]6731      4.033     0.042     -67    47
# Comp:  2              HeII4687    0.09499     0.048     -67    47
# Comp:  2               HeI5876      1.368     0.039     -67    47
# Comp:  2          [OIII]5007_d      32.33      0.12     -67    47
# Comp:  2            [OI]6300_d     0.6376     0.040     -67    47
# Comp:  2           [NII]6583_d      8.691     0.061     -67    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -58        35
#  comp.  2:       -65        40
# chi2/DOF: 3.472; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.05     0.082     -58    35
# Comp:  1                Halpha      37.38     0.096     -58    35
# Comp:  2             [SII]6716      5.191     0.044     -65    40
# Comp:  2             [SII]6731      3.931     0.041     -65    40
# Comp:  2              HeII4687     0.1318     0.047     -65    40
# Comp:  2               HeI5876      1.358     0.038     -65    40
# Comp:  2          [OIII]5007_d      31.16      0.12     -65    40
# Comp:  2            [OI]6300_d     0.6008     0.039     -65    40
# Comp:  2           [NII]6583_d      8.074     0.060     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        24
#  comp.  1:       -61        34
#  comp.  2:       -62        43
# chi2/DOF: 3.703; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.14     0.082     -61    34
# Comp:  1                Halpha      37.55     0.096     -61    34
# Comp:  2             [SII]6716      5.079     0.045     -62    43
# Comp:  2             [SII]6731      3.675     0.041     -62    43
# Comp:  2              HeII4687     0.1437     0.048     -62    43
# Comp:  2               HeI5876      1.404     0.038     -62    43
# Comp:  2          [OIII]5007_d      31.90      0.12     -62    43
# Comp:  2            [OI]6300_d     0.7777     0.040     -62    43
# Comp:  2           [NII]6583_d      9.070     0.060     -62    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        34
#  comp.  1:       -65        35
#  comp.  2:       -65        40
# chi2/DOF: 3.805; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.27     0.082     -65    35
# Comp:  1                Halpha      35.41     0.096     -65    35
# Comp:  2             [SII]6716      5.132     0.044     -65    40
# Comp:  2             [SII]6731      4.068     0.041     -65    40
# Comp:  2              HeII4687     0.1875     0.047     -65    40
# Comp:  2               HeI5876      1.412     0.038     -65    40
# Comp:  2          [OIII]5007_d      30.58      0.12     -65    40
# Comp:  2            [OI]6300_d     0.6538     0.039     -65    40
# Comp:  2           [NII]6583_d      9.067     0.060     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        32
#  comp.  1:       -61        34
#  comp.  2:       -66        49
# chi2/DOF: 3.793; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.80     0.082     -61    34
# Comp:  1                Halpha      37.42     0.096     -61    34
# Comp:  2             [SII]6716      5.206     0.045     -66    49
# Comp:  2             [SII]6731      3.956     0.042     -66    49
# Comp:  2              HeII4687     0.1423     0.049     -66    49
# Comp:  2               HeI5876      1.508     0.039     -66    49
# Comp:  2          [OIII]5007_d      32.05      0.12     -66    49
# Comp:  2            [OI]6300_d     0.6461     0.041     -66    49
# Comp:  2           [NII]6583_d      9.324     0.061     -66    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        19
#  comp.  1:       -63        36
#  comp.  2:       -65        40
# chi2/DOF: 4.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.20     0.082     -63    36
# Comp:  1                Halpha      34.57     0.096     -63    36
# Comp:  2             [SII]6716      5.258     0.044     -65    40
# Comp:  2             [SII]6731      3.488     0.041     -65    40
# Comp:  2              HeII4687     0.1685     0.047     -65    40
# Comp:  2               HeI5876      1.397     0.038     -65    40
# Comp:  2          [OIII]5007_d      31.09      0.12     -65    40
# Comp:  2            [OI]6300_d     0.6262     0.040     -65    40
# Comp:  2           [NII]6583_d      8.975     0.060     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        28
#  comp.  1:       -65        25
#  comp.  2:       -65        41
# chi2/DOF: 3.971; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.87     0.080     -65    25
# Comp:  1                Halpha      35.29     0.096     -65    25
# Comp:  2             [SII]6716      5.175     0.044     -65    41
# Comp:  2             [SII]6731      3.761     0.041     -65    41
# Comp:  2              HeII4687     0.1004     0.048     -65    41
# Comp:  2               HeI5876      1.373     0.038     -65    41
# Comp:  2          [OIII]5007_d      31.20      0.12     -65    41
# Comp:  2            [OI]6300_d     0.6590     0.040     -65    41
# Comp:  2           [NII]6583_d      8.385     0.060     -65    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        21
#  comp.  1:       -63        38
#  comp.  2:       -63        45
# chi2/DOF: 3.924; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.57     0.082     -63    38
# Comp:  1                Halpha      35.19     0.096     -63    38
# Comp:  2             [SII]6716      5.241     0.045     -63    45
# Comp:  2             [SII]6731      3.681     0.041     -63    45
# Comp:  2              HeII4687     0.1539     0.048     -63    45
# Comp:  2               HeI5876      1.324     0.038     -63    45
# Comp:  2          [OIII]5007_d      32.14      0.12     -63    45
# Comp:  2            [OI]6300_d     0.6866     0.040     -63    45
# Comp:  2           [NII]6583_d      8.946     0.060     -63    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        36
#  comp.  1:       -59        35
#  comp.  2:       -64        46
# chi2/DOF: 3.598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.84     0.082     -59    35
# Comp:  1                Halpha      37.16     0.096     -59    35
# Comp:  2             [SII]6716      5.301     0.045     -64    46
# Comp:  2             [SII]6731      3.930     0.042     -64    46
# Comp:  2              HeII4687     0.1193     0.048     -64    46
# Comp:  2               HeI5876      1.476     0.039     -64    46
# Comp:  2          [OIII]5007_d      31.36      0.12     -64    46
# Comp:  2            [OI]6300_d     0.6324     0.040     -64    46
# Comp:  2           [NII]6583_d      9.330     0.060     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -63        32
#  comp.  2:       -65        46
# chi2/DOF: 4.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.05     0.081     -63    32
# Comp:  1                Halpha      36.35     0.096     -63    32
# Comp:  2             [SII]6716      5.289     0.045     -65    46
# Comp:  2             [SII]6731      3.945     0.042     -65    46
# Comp:  2              HeII4687     0.1583     0.048     -65    46
# Comp:  2               HeI5876      1.370     0.039     -65    46
# Comp:  2          [OIII]5007_d      31.71      0.12     -65    46
# Comp:  2            [OI]6300_d     0.6461     0.040     -65    46
# Comp:  2           [NII]6583_d      8.315     0.061     -65    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -69        24
#  comp.  2:       -64        44
# chi2/DOF: 3.347; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.99     0.080     -69    24
# Comp:  1                Halpha      32.88     0.095     -69    24
# Comp:  2             [SII]6716      5.087     0.045     -64    44
# Comp:  2             [SII]6731      3.754     0.041     -64    44
# Comp:  2              HeII4687     0.1216     0.048     -64    44
# Comp:  2               HeI5876      1.376     0.038     -64    44
# Comp:  2          [OIII]5007_d      31.91      0.12     -64    44
# Comp:  2            [OI]6300_d     0.5678     0.040     -64    44
# Comp:  2           [NII]6583_d      9.260     0.060     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -70        28
#  comp.  2:       -66        47
# chi2/DOF: 3.559; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.86     0.080     -70    28
# Comp:  1                Halpha      33.90     0.096     -70    28
# Comp:  2             [SII]6716      5.254     0.045     -66    47
# Comp:  2             [SII]6731      4.072     0.042     -66    47
# Comp:  2              HeII4687     0.1373     0.049     -66    47
# Comp:  2               HeI5876      1.485     0.039     -66    47
# Comp:  2          [OIII]5007_d      32.69      0.12     -66    47
# Comp:  2            [OI]6300_d     0.5809     0.040     -66    47
# Comp:  2           [NII]6583_d      9.098     0.061     -66    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -68        24
#  comp.  2:       -67        48
# chi2/DOF: 3.404; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.75     0.080     -68    24
# Comp:  1                Halpha      32.84     0.095     -68    24
# Comp:  2             [SII]6716      5.334     0.045     -67    48
# Comp:  2             [SII]6731      4.196     0.042     -67    48
# Comp:  2              HeII4687     0.1464     0.049     -67    48
# Comp:  2               HeI5876      1.474     0.039     -67    48
# Comp:  2          [OIII]5007_d      32.04      0.12     -67    48
# Comp:  2            [OI]6300_d     0.6738     0.041     -67    48
# Comp:  2           [NII]6583_d      9.024     0.061     -67    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -69        26
#  comp.  2:       -65        45
# chi2/DOF: 3.686; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.61     0.080     -69    26
# Comp:  1                Halpha      33.53     0.095     -69    26
# Comp:  2             [SII]6716      5.311     0.045     -65    45
# Comp:  2             [SII]6731      3.938     0.041     -65    45
# Comp:  2              HeII4687     0.1346     0.048     -65    45
# Comp:  2               HeI5876      1.486     0.038     -65    45
# Comp:  2          [OIII]5007_d      31.58      0.12     -65    45
# Comp:  2            [OI]6300_d     0.6252     0.040     -65    45
# Comp:  2           [NII]6583_d      8.620     0.060     -65    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        40
#  comp.  1:       -60        39
#  comp.  2:       -66        48
# chi2/DOF: 3.640; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.57     0.082     -60    39
# Comp:  1                Halpha      36.79     0.096     -60    39
# Comp:  2             [SII]6716      5.323     0.045     -66    48
# Comp:  2             [SII]6731      4.338     0.042     -66    48
# Comp:  2              HeII4687     0.1672     0.049     -66    48
# Comp:  2               HeI5876      1.450     0.039     -66    48
# Comp:  2          [OIII]5007_d      32.00      0.12     -66    48
# Comp:  2            [OI]6300_d     0.6842     0.041     -66    48
# Comp:  2           [NII]6583_d      8.749     0.061     -66    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        31
#  comp.  1:       -59        39
#  comp.  2:       -66        41
# chi2/DOF: 3.494; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.50     0.082     -59    39
# Comp:  1                Halpha      37.15     0.096     -59    39
# Comp:  2             [SII]6716      5.103     0.044     -66    41
# Comp:  2             [SII]6731      3.901     0.041     -66    41
# Comp:  2              HeII4687     0.1468     0.048     -66    41
# Comp:  2               HeI5876      1.434     0.038     -66    41
# Comp:  2          [OIII]5007_d      30.78      0.12     -66    41
# Comp:  2            [OI]6300_d     0.7330     0.040     -66    41
# Comp:  2           [NII]6583_d      8.757     0.060     -66    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        29
#  comp.  1:       -64        37
#  comp.  2:       -65        50
# chi2/DOF: 3.947; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.49     0.082     -64    37
# Comp:  1                Halpha      34.95     0.096     -64    37
# Comp:  2             [SII]6716      5.214     0.045     -65    50
# Comp:  2             [SII]6731      3.595     0.042     -65    50
# Comp:  2              HeII4687     0.1535     0.049     -65    50
# Comp:  2               HeI5876      1.530     0.039     -65    50
# Comp:  2          [OIII]5007_d      32.20      0.12     -65    50
# Comp:  2            [OI]6300_d     0.6105     0.041     -65    50
# Comp:  2           [NII]6583_d      8.989     0.061     -65    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        19
#  comp.  1:       -66        27
#  comp.  2:       -64        41
# chi2/DOF: 3.908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.87     0.080     -66    27
# Comp:  1                Halpha      35.76     0.096     -66    27
# Comp:  2             [SII]6716      5.214     0.044     -64    41
# Comp:  2             [SII]6731      3.949     0.041     -64    41
# Comp:  2              HeII4687     0.1620     0.048     -64    41
# Comp:  2               HeI5876      1.384     0.038     -64    41
# Comp:  2          [OIII]5007_d      30.93      0.12     -64    41
# Comp:  2            [OI]6300_d     0.6177     0.040     -64    41
# Comp:  2           [NII]6583_d      8.996     0.060     -64    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -64        30
#  comp.  2:       -67        47
# chi2/DOF: 3.957; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.59     0.081     -64    30
# Comp:  1                Halpha      35.70     0.096     -64    30
# Comp:  2             [SII]6716      5.223     0.045     -67    47
# Comp:  2             [SII]6731      3.820     0.042     -67    47
# Comp:  2              HeII4687     0.1191     0.049     -67    47
# Comp:  2               HeI5876      1.492     0.039     -67    47
# Comp:  2          [OIII]5007_d      31.71      0.12     -67    47
# Comp:  2            [OI]6300_d     0.6892     0.040     -67    47
# Comp:  2           [NII]6583_d      8.544     0.061     -67    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        14
#  comp.  1:       -64        35
#  comp.  2:       -64        40
# chi2/DOF: 3.982; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.30     0.082     -64    35
# Comp:  1                Halpha      35.46     0.096     -64    35
# Comp:  2             [SII]6716      5.232     0.044     -64    40
# Comp:  2             [SII]6731      3.769     0.041     -64    40
# Comp:  2              HeII4687     0.1551     0.047     -64    40
# Comp:  2               HeI5876      1.394     0.038     -64    40
# Comp:  2          [OIII]5007_d      30.85      0.12     -64    40
# Comp:  2            [OI]6300_d     0.6264     0.040     -64    40
# Comp:  2           [NII]6583_d      8.982     0.060     -64    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        25
#  comp.  1:       -60        40
#  comp.  2:       -66        50
# chi2/DOF: 3.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.16     0.083     -60    40
# Comp:  1                Halpha      37.31     0.096     -60    40
# Comp:  2             [SII]6716      5.433     0.045     -66    50
# Comp:  2             [SII]6731      4.220     0.042     -66    50
# Comp:  2              HeII4687     0.1882     0.049     -66    50
# Comp:  2               HeI5876      1.395     0.039     -66    50
# Comp:  2          [OIII]5007_d      32.22      0.12     -66    50
# Comp:  2            [OI]6300_d     0.6034     0.041     -66    50
# Comp:  2           [NII]6583_d      9.218     0.061     -66    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        23
#  comp.  1:       -65        34
#  comp.  2:       -66        46
# chi2/DOF: 4.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.54     0.081     -65    34
# Comp:  1                Halpha      35.67     0.096     -65    34
# Comp:  2             [SII]6716      5.179     0.045     -66    46
# Comp:  2             [SII]6731      3.690     0.042     -66    46
# Comp:  2              HeII4687     0.1303     0.048     -66    46
# Comp:  2               HeI5876      1.493     0.039     -66    46
# Comp:  2          [OIII]5007_d      32.04      0.12     -66    46
# Comp:  2            [OI]6300_d     0.6588     0.040     -66    46
# Comp:  2           [NII]6583_d      8.544     0.060     -66    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -63        40
#  comp.  2:       -66        43
# chi2/DOF: 3.674; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.26     0.083     -63    40
# Comp:  1                Halpha      35.33     0.097     -63    40
# Comp:  2             [SII]6716      5.274     0.045     -66    43
# Comp:  2             [SII]6731      4.135     0.041     -66    43
# Comp:  2              HeII4687     0.1630     0.048     -66    43
# Comp:  2               HeI5876      1.472     0.038     -66    43
# Comp:  2          [OIII]5007_d      31.17      0.12     -66    43
# Comp:  2            [OI]6300_d     0.5771     0.040     -66    43
# Comp:  2           [NII]6583_d      9.533     0.060     -66    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        27
#  comp.  1:       -64        25
#  comp.  2:       -64        46
# chi2/DOF: 3.907; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.20     0.080     -64    25
# Comp:  1                Halpha      35.66     0.096     -64    25
# Comp:  2             [SII]6716      5.246     0.045     -64    46
# Comp:  2             [SII]6731      3.556     0.041     -64    46
# Comp:  2              HeII4687     0.1956     0.048     -64    46
# Comp:  2               HeI5876      1.371     0.039     -64    46
# Comp:  2          [OIII]5007_d      31.03      0.12     -64    46
# Comp:  2            [OI]6300_d     0.6561     0.040     -64    46
# Comp:  2           [NII]6583_d      8.273     0.060     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -61        38
#  comp.  2:       -64        41
# chi2/DOF: 3.802; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.99     0.082     -61    38
# Comp:  1                Halpha      35.33     0.096     -61    38
# Comp:  2             [SII]6716      5.268     0.044     -64    41
# Comp:  2             [SII]6731      3.756     0.041     -64    41
# Comp:  2              HeII4687     0.2084     0.047     -64    41
# Comp:  2               HeI5876      1.315     0.038     -64    41
# Comp:  2          [OIII]5007_d      31.67      0.12     -64    41
# Comp:  2            [OI]6300_d     0.6550     0.040     -64    41
# Comp:  2           [NII]6583_d      7.916     0.060     -64    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        41
#  comp.  1:       -60        34
#  comp.  2:       -67        49
# chi2/DOF: 3.815; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.17     0.082     -60    34
# Comp:  1                Halpha      37.03     0.096     -60    34
# Comp:  2             [SII]6716      5.212     0.045     -67    49
# Comp:  2             [SII]6731      3.864     0.042     -67    49
# Comp:  2              HeII4687     0.1637     0.049     -67    49
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.66     0.080     -68    29
# Comp:  1                Halpha      33.68     0.096     -68    29
# Comp:  2             [SII]6716      5.277     0.045     -66    50
# Comp:  2             [SII]6731      3.886     0.042     -66    50
# Comp:  2              HeII4687     0.1257     0.049     -66    50
# Comp:  2               HeI5876      1.441     0.039     -66    50
# Comp:  2          [OIII]5007_d      32.20      0.12     -66    50
# Comp:  2            [OI]6300_d     0.6352     0.041     -66    50
# Comp:  2           [NII]6583_d      8.436     0.061     -66    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        29
#  comp.  1:       -67        28
#  comp.  2:       -64        46
# chi2/DOF: 3.942; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.23     0.080     -67    28
# Comp:  1                Halpha      34.24     0.096     -67    28
# Comp:  2             [SII]6716      5.254     0.045     -64    46
# Comp:  2             [SII]6731      3.886     0.042     -64    46
# Comp:  2              HeII4687     0.1778     0.048     -64    46
# Comp:  2               HeI5876      1.363     0.039     -64    46
# Comp:  2          [OIII]5007_d      32.06      0.12     -64    46
# Comp:  2            [OI]6300_d     0.6161     0.040     -64    46
# Comp:  2           [NII]6583_d      9.353     0.060     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        25
#  comp.  1:       -60        40
#  comp.  2:       -68        40
# chi2/DOF: 3.506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.45     0.083     -60    40
# Comp:  1                Halpha      36.77     0.096     -60    40
# Comp:  2             [SII]6716      5.114     0.044     -68    40
# Comp:  2             [SII]6731      3.761     0.041     -68    40
# Comp:  2              HeII4687     0.1462     0.047     -68    40
# Comp:  2               HeI5876      1.330     0.038     -68    40
# Comp:  2          [OIII]5007_d      31.73      0.12     -68    40
# Comp:  2            [OI]6300_d     0.7284     0.040     -68    40
# Comp:  2           [NII]6583_d      8.371     0.060     -68    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        29
#  comp.  1:       -60        38
#  comp.  2:       -65        43
# chi2/DOF: 3.484; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.05     0.082     -60    38
# Comp:  1                Halpha      36.64     0.096     -60    38
# Comp:  2             [SII]6716      5.188     0.045     -65    43
# Comp:  2             [SII]6731      3.852     0.041     -65    43
# Comp:  2              HeII4687     0.2011     0.048     -65    43
# Comp:  2               HeI5876      1.375     0.038     -65    43
# Comp:  2          [OIII]5007_d      31.95      0.12     -65    43
# Comp:  2            [OI]6300_d     0.7488     0.040     -65    43
# Comp:  2           [NII]6583_d      7.983     0.060     -65    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -68        28
#  comp.  2:       -66        39
# chi2/DOF: 3.802; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.60     0.080     -68    28
# Comp:  1                Halpha      34.05     0.096     -68    28
# Comp:  2             [SII]6716      5.238     0.044     -66    39
# Comp:  2             [SII]6731      3.783     0.041     -66    39
# Comp:  2              HeII4687     0.1761     0.047     -66    39
# Comp:  2               HeI5876      1.324     0.038     -66    39
# Comp:  2          [OIII]5007_d      31.31      0.12     -66    39
# Comp:  2            [OI]6300_d     0.7185     0.039     -66    39
# Comp:  2           [NII]6583_d      8.931     0.060     -66    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -71        26
#  comp.  2:       -68        42
# chi2/DOF: 3.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.57     0.080     -71    26
# Comp:  1                Halpha      33.67     0.095     -71    26
# Comp:  2             [SII]6716      5.155     0.044     -68    42
# Comp:  2             [SII]6731      3.840     0.041     -68    42
# Comp:  2              HeII4687     0.1318     0.048     -68    42
# Comp:  2               HeI5876      1.367     0.038     -68    42
# Comp:  2          [OIII]5007_d      31.62      0.12     -68    42
# Comp:  2            [OI]6300_d     0.6275     0.040     -68    42
# Comp:  2           [NII]6583_d      8.847     0.060     -68    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -60        38
#  comp.  2:       -69        45
# chi2/DOF: 3.588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.49     0.082     -60    38
# Comp:  1                Halpha      37.17     0.096     -60    38
# Comp:  2             [SII]6716      5.217     0.045     -69    45
# Comp:  2             [SII]6731      4.137     0.041     -69    45
# Comp:  2              HeII4687     0.1366     0.048     -69    45
# Comp:  2               HeI5876      1.440     0.038     -69    45
# Comp:  2          [OIII]5007_d      31.51      0.12     -69    45
# Comp:  2            [OI]6300_d     0.7163     0.040     -69    45
# Comp:  2           [NII]6583_d      8.594     0.060     -69    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        11
#  comp.  1:       -58        33
#  comp.  2:       -66        37
# chi2/DOF: 3.326; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.91     0.082     -58    33
# Comp:  1                Halpha      37.02     0.096     -58    33
# Comp:  2             [SII]6716      5.018     0.044     -66    37
# Comp:  2             [SII]6731      3.870     0.041     -66    37
# Comp:  2              HeII4687     0.1410     0.047     -66    37
# Comp:  2               HeI5876      1.460     0.038     -66    37
# Comp:  2          [OIII]5007_d      30.96      0.12     -66    37
# Comp:  2            [OI]6300_d     0.7112     0.039     -66    37
# Comp:  2           [NII]6583_d      9.314     0.059     -66    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        37
#  comp.  1:       -59        38
#  comp.  2:       -66        50
# chi2/DOF: 3.638; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.38     0.082     -59    38
# Comp:  1                Halpha      37.02     0.096     -59    38
# Comp:  2             [SII]6716      5.300     0.045     -66    50
# Comp:  2             [SII]6731      3.988     0.042     -66    50
# Comp:  2              HeII4687     0.1547     0.049     -66    50
# Comp:  2               HeI5876      1.396     0.039     -66    50
# Comp:  2          [OIII]5007_d      31.47      0.12     -66    50
# Comp:  2            [OI]6300_d     0.7040     0.041     -66    50
# Comp:  2           [NII]6583_d      9.095     0.061     -66    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        24
#  comp.  1:       -65        24
#  comp.  2:       -67        49
# chi2/DOF: 3.725; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.70     0.080     -65    24
# Comp:  1                Halpha      36.17     0.096     -65    24
# Comp:  2             [SII]6716      5.126     0.045     -67    49
# Comp:  2             [SII]6731      3.857     0.042     -67    49
# Comp:  2              HeII4687     0.1283     0.049     -67    49
# Comp:  2               HeI5876      1.468     0.039     -67    49
# Comp:  2          [OIII]5007_d      32.26      0.12     -67    49
# Comp:  2            [OI]6300_d     0.6903     0.041     -67    49
# Comp:  2           [NII]6583_d      9.116     0.061     -67    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        25
#  comp.  1:       -64        39
#  comp.  2:       -65        44
# chi2/DOF: 3.776; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      17.25     0.082     -64    39
# Comp:  1                Halpha      35.22     0.096     -64    39
# Comp:  2             [SII]6716      5.214     0.045     -65    44
# Comp:  2             [SII]6731      4.056     0.041     -65    44
# Comp:  2              HeII4687     0.1385     0.048     -65    44
# Comp:  2               HeI5876      1.415     0.038     -65    44
# Comp:  2          [OIII]5007_d      30.72      0.12     -65    44
# Comp:  2            [OI]6300_d     0.6835     0.040     -65    44
# Comp:  2           [NII]6583_d      9.372     0.060     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -60        39
#  comp.  2:       -66        42
# chi2/DOF: 3.658; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.49     0.082     -60    39
# Comp:  1                Halpha      36.82     0.096     -60    39
# Comp:  2             [SII]6716      5.237     0.045     -66    42
# Comp:  2             [SII]6731      4.162     0.041     -66    42
# Comp:  2              HeII4687    0.09493     0.048     -66    42
# Comp:  2               HeI5876      1.365     0.038     -66    42
# Comp:  2          [OIII]5007_d      31.05      0.12     -66    42
# Comp:  2            [OI]6300_d     0.7174     0.040     -66    42
# Comp:  2           [NII]6583_d      8.653     0.060     -66    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        26
#  comp.  1:       -64        33
#  comp.  2:       -69        45
# chi2/DOF: 4.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.50     0.081     -64    33
# Comp:  1                Halpha      34.61     0.096     -64    33
# Comp:  2             [SII]6716      5.215     0.045     -69    45
# Comp:  2             [SII]6731      3.694     0.041     -69    45
# Comp:  2              HeII4687     0.1822     0.048     -69    45
# Comp:  2               HeI5876      1.344     0.038     -69    45
# Comp:  2          [OIII]5007_d      31.93      0.12     -69    45
# Comp:  2            [OI]6300_d     0.7320     0.040     -69    45
# Comp:  2           [NII]6583_d      8.800     0.060     -69    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        44
#  comp.  1:       -61        35
#  comp.  2:       -62        45
# chi2/DOF: 3.864; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.07     0.082     -61    35
# Comp:  1                Halpha      36.91     0.096     -61    35
# Comp:  2             [SII]6716      5.120     0.045     -62    45
# Comp:  2             [SII]6731      4.031     0.041     -62    45
# Comp:  2              HeII4687     0.1191     0.048     -62    45
# Comp:  2               HeI5876      1.370     0.038     -62    45
# Comp:  2          [OIII]5007_d      31.62      0.12     -62    45
# Comp:  2            [OI]6300_d     0.5899     0.040     -62    45
# Comp:  2           [NII]6583_d      8.657     0.060     -62    45
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.95170539, 1.8227938 , 0.13114599, 0.2891991 , 0.03166086,
#        0.0641795 , 0.60094966, 0.06405694, 0.57359812])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([15.36508423, 48.29708778,  7.32772167,  5.50704806,  0.14414596,
#         1.70336838, 33.04628597,  0.88720985, 12.03132685])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_10_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_10", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_10_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum_10_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_10_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta  28.773146    1.782194
# 1        Halpha  90.442666    3.413422
# 2     [SII]6716  13.722125    0.245588
# 3     [SII]6731  10.312674    0.541563
# 4      HeII4687   0.269932    0.059289
# 5       HeI5876   3.189782    0.120185
# 6  [OIII]5007_d  61.883528    1.125357
# 7    [OI]6300_d   1.661417    0.119955
# 8   [NII]6583_d  22.530246    1.074138
#           Name       Flux  Error_flux
# 0        Hbeta  28.773146    1.782194
# 1       Halpha  90.442666    3.413422
# 2    [SII]6716  13.722125    0.245588
# 3    [SII]6731  10.312674    0.541563
# 4     HeII4687   0.269932    0.059289
# 5      HeI5876   3.189782    0.120185
# 6   [OIII]4959  15.470882    1.125357
# 7   [OIII]5007  46.412646    1.125357
# 8     [OI]6300   1.246063    0.119955
# 9     [OI]6364   0.415354    0.119955
# 10   [NII]6548   5.632562    1.074138
# 11   [NII]6583  16.897685    1.074138

# %%
np.median(flux_rf_rebin)
# Out:
# 1.8726318676205471
