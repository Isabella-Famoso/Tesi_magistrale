# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_2/UGC-7596_2_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_2/UGC-7596_2_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     345   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        44   (2094, 964)   float32

# %%
image_cut = image[77:177, 0:1890]
image_error_cut = image_error[77:177, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 52*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax=np.percentile(image_cut, 95))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.00189
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)
seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/PSF/Real_seeing_UGC7596.txt")
sigma = seeing[0]/2.35

# %%
l_HA
# Out:
# 6575.40407

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
def chi_quad(x, y, y_err, params):
    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, y_err, params): #k=number of model parameter, N=number of data points
    return chi_quad(x, y, y_err, params) + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, y_err, params):
        return chi_quad(x, y, y_err, params) + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20),  # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 38.44233872821323
# differential_evolution step 2: f(x)= 33.74117343477508
# differential_evolution step 3: f(x)= 27.297822282374888
# differential_evolution step 4: f(x)= 20.58396646010648
# differential_evolution step 5: f(x)= 20.58396646010648
# differential_evolution step 6: f(x)= 18.532932635969082
# differential_evolution step 7: f(x)= 18.373675462745208
# differential_evolution step 8: f(x)= 18.373675462745208
# differential_evolution step 9: f(x)= 17.797277516494695
# differential_evolution step 10: f(x)= 17.797277516494695
# differential_evolution step 11: f(x)= 17.797277516494695
# differential_evolution step 12: f(x)= 17.78713621223433
# differential_evolution step 13: f(x)= 17.198996548645304
# differential_evolution step 14: f(x)= 16.990552787893964
# differential_evolution step 15: f(x)= 16.42375905805395
# differential_evolution step 16: f(x)= 16.42375905805395
# differential_evolution step 17: f(x)= 16.42375905805395
# differential_evolution step 18: f(x)= 16.42375905805395
# differential_evolution step 19: f(x)= 16.42375905805395
# differential_evolution step 20: f(x)= 16.42375905805395
# differential_evolution step 21: f(x)= 16.42375905805395
# differential_evolution step 22: f(x)= 16.42375905805395
# differential_evolution step 23: f(x)= 16.387572732925285
# differential_evolution step 24: f(x)= 16.387572732925285
# differential_evolution step 25: f(x)= 16.37398252785891
# differential_evolution step 26: f(x)= 16.330174109258962
# differential_evolution step 27: f(x)= 16.330174109258962
# differential_evolution step 28: f(x)= 16.330174109258962
# differential_evolution step 29: f(x)= 16.32404382301074
# differential_evolution step 30: f(x)= 16.32404382301074
# differential_evolution step 31: f(x)= 16.32404382301074
# differential_evolution step 32: f(x)= 16.316211759899367
# differential_evolution step 33: f(x)= 16.316211759899367
# differential_evolution step 34: f(x)= 16.316211759899367
# differential_evolution step 35: f(x)= 16.316211759899367
# differential_evolution step 36: f(x)= 16.316211759899367
# differential_evolution step 37: f(x)= 16.316211759899367
# differential_evolution step 38: f(x)= 16.316211759899367
# differential_evolution step 39: f(x)= 16.313847873546607
# differential_evolution step 40: f(x)= 16.313847873546607
# differential_evolution step 41: f(x)= 16.31296083785579
# differential_evolution step 42: f(x)= 16.31296083785579
# differential_evolution step 43: f(x)= 16.31296083785579
# differential_evolution step 44: f(x)= 16.31296083785579
# differential_evolution step 45: f(x)= 16.312827356001037
# differential_evolution step 46: f(x)= 16.312827356001037
# differential_evolution step 47: f(x)= 16.312827356001037
# differential_evolution step 48: f(x)= 16.312449210867783
# differential_evolution step 49: f(x)= 16.311701365520683
# differential_evolution step 50: f(x)= 16.311701365520683
# differential_evolution step 51: f(x)= 16.311701365520683
# differential_evolution step 52: f(x)= 16.311701365520683
# differential_evolution step 53: f(x)= 16.311699468620496
# differential_evolution step 54: f(x)= 16.311585254872455
# differential_evolution step 55: f(x)= 16.311585254872455
# differential_evolution step 56: f(x)= 16.311585254872455
# differential_evolution step 57: f(x)= 16.311585254872455
# differential_evolution step 58: f(x)= 16.311585254872455
# differential_evolution step 59: f(x)= 16.311585254872455
# differential_evolution step 60: f(x)= 16.311585254872455
# differential_evolution step 61: f(x)= 16.311585254872455
# differential_evolution step 62: f(x)= 16.311579753250705
# differential_evolution step 63: f(x)= 16.311579753250705
# differential_evolution step 64: f(x)= 16.311579753250705
# differential_evolution step 65: f(x)= 16.311579753250705
# differential_evolution step 66: f(x)= 16.311543251174925
# differential_evolution step 67: f(x)= 16.311543251174925
# differential_evolution step 68: f(x)= 16.311543251174925
# differential_evolution step 69: f(x)= 16.311543251174925
# differential_evolution step 70: f(x)= 16.311543251174925
# differential_evolution step 71: f(x)= 16.311543251174925
# differential_evolution step 72: f(x)= 16.31152686792095
# differential_evolution step 73: f(x)= 16.31152686792095
# differential_evolution step 74: f(x)= 16.31152424346162
# differential_evolution step 75: f(x)= 16.31152424346162
# differential_evolution step 76: f(x)= 16.311521386059496
# differential_evolution step 77: f(x)= 16.311521386059496
# differential_evolution step 78: f(x)= 16.311521386059496
# differential_evolution step 79: f(x)= 16.311519491112072
# differential_evolution step 80: f(x)= 16.311519491112072
# differential_evolution step 81: f(x)= 16.311519491112072
# differential_evolution step 82: f(x)= 16.3115188539644
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.28126711 42.85691149  0.72146382 37.        ]
# Chi quadro minimo: 16.31151752157389

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic = np.zeros(6)
bic = np.zeros(6)
chi_quadr = np.zeros(6)
red_chi = np.zeros(6)
aic[0] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params1)
chi_quadr[0] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params1)
bic[0] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params1)
print(aic[0], chi_quadr[0], bic[0], len(best_params1))

dof_HA = len(radial_profile_HA) - len(best_params1)
print('Reduced chi square:', chi_quadr[0] / dof_HA)
red_chi[0] = chi_quadr[0] / dof_HA
plt.savefig('AIC_1')
# Out:
# 141052.44105115245 141044.0932250655 141063.24319203664 4
# Reduced chi square: 1215.8973553884957
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20)   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (18, 23)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 156.996319337766
# differential_evolution step 2: f(x)= 156.996319337766
# differential_evolution step 3: f(x)= 44.70933161788045
# differential_evolution step 4: f(x)= 28.18919618689065
# differential_evolution step 5: f(x)= 28.18919618689065
# differential_evolution step 6: f(x)= 16.53365650258749
# differential_evolution step 7: f(x)= 16.53365650258749
# differential_evolution step 8: f(x)= 16.53365650258749
# differential_evolution step 9: f(x)= 16.53365650258749
# differential_evolution step 10: f(x)= 9.795852506044412
# differential_evolution step 11: f(x)= 9.795852506044412
# differential_evolution step 12: f(x)= 9.697873625833585
# differential_evolution step 13: f(x)= 9.697873625833585
# differential_evolution step 14: f(x)= 9.697873625833585
# differential_evolution step 15: f(x)= 9.697873625833585
# differential_evolution step 16: f(x)= 9.697873625833585
# differential_evolution step 17: f(x)= 9.697873625833585
# differential_evolution step 18: f(x)= 9.666765206262252
# differential_evolution step 19: f(x)= 9.666765206262252
# differential_evolution step 20: f(x)= 9.666765206262252
# differential_evolution step 21: f(x)= 9.666765206262252
# differential_evolution step 22: f(x)= 8.9067680921295
# differential_evolution step 23: f(x)= 7.836521952711343
# differential_evolution step 24: f(x)= 7.836521952711343
# differential_evolution step 25: f(x)= 7.836521952711343
# differential_evolution step 26: f(x)= 7.836521952711343
# differential_evolution step 27: f(x)= 6.400376720312757
# differential_evolution step 28: f(x)= 6.400376720312757
# differential_evolution step 29: f(x)= 6.400376720312757
# differential_evolution step 30: f(x)= 6.400376720312757
# differential_evolution step 31: f(x)= 6.400376720312757
# differential_evolution step 32: f(x)= 6.400376720312757
# differential_evolution step 33: f(x)= 6.400376720312757
# differential_evolution step 34: f(x)= 6.400376720312757
# differential_evolution step 35: f(x)= 6.400376720312757
# differential_evolution step 36: f(x)= 6.400376720312757
# differential_evolution step 37: f(x)= 6.352756120470888
# differential_evolution step 38: f(x)= 6.215390841350377
# differential_evolution step 39: f(x)= 6.100301620531243
# differential_evolution step 40: f(x)= 6.100301620531243
# differential_evolution step 41: f(x)= 6.100301620531243
# differential_evolution step 42: f(x)= 6.100301620531243
# differential_evolution step 43: f(x)= 6.100301620531243
# differential_evolution step 44: f(x)= 6.100301620531243
# differential_evolution step 45: f(x)= 6.100301620531243
# differential_evolution step 46: f(x)= 6.031687432775144
# differential_evolution step 47: f(x)= 6.031687432775144
# differential_evolution step 48: f(x)= 5.97623090006569
# differential_evolution step 49: f(x)= 5.97623090006569
# differential_evolution step 50: f(x)= 5.97623090006569
# differential_evolution step 51: f(x)= 5.97623090006569
# differential_evolution step 52: f(x)= 5.97623090006569
# differential_evolution step 53: f(x)= 5.97623090006569
# differential_evolution step 54: f(x)= 5.97623090006569
# differential_evolution step 55: f(x)= 5.97623090006569
# differential_evolution step 56: f(x)= 5.97623090006569
# differential_evolution step 57: f(x)= 5.97623090006569
# differential_evolution step 58: f(x)= 5.97623090006569
# differential_evolution step 59: f(x)= 5.97623090006569
# differential_evolution step 60: f(x)= 5.923386649678314
# differential_evolution step 61: f(x)= 5.923386649678314
# differential_evolution step 62: f(x)= 5.826543001671331
# differential_evolution step 63: f(x)= 5.826543001671331
# differential_evolution step 64: f(x)= 5.826543001671331
# differential_evolution step 65: f(x)= 5.810810902091594
# differential_evolution step 66: f(x)= 5.810810902091594
# differential_evolution step 67: f(x)= 5.810810902091594
# differential_evolution step 68: f(x)= 5.810810902091594
# differential_evolution step 69: f(x)= 5.810810902091594
# differential_evolution step 70: f(x)= 5.810810902091594
# differential_evolution step 71: f(x)= 5.810810902091594
# differential_evolution step 72: f(x)= 5.810810902091594
# differential_evolution step 73: f(x)= 5.810810902091594
# differential_evolution step 74: f(x)= 5.810810902091594
# differential_evolution step 75: f(x)= 5.810810902091594
# differential_evolution step 76: f(x)= 5.810810902091594
# differential_evolution step 77: f(x)= 5.810810902091594
# differential_evolution step 78: f(x)= 5.810810902091594
# differential_evolution step 79: f(x)= 5.810810902091594
# differential_evolution step 80: f(x)= 5.810810902091594
# differential_evolution step 81: f(x)= 5.810810902091594
# differential_evolution step 82: f(x)= 5.810810902091594
# differential_evolution step 83: f(x)= 5.800743393454055
# differential_evolution step 84: f(x)= 5.800743393454055
# differential_evolution step 85: f(x)= 5.800743393454055
# differential_evolution step 86: f(x)= 5.800743393454055
# differential_evolution step 87: f(x)= 5.800743393454055
# differential_evolution step 88: f(x)= 5.800743393454055
# differential_evolution step 89: f(x)= 5.799209884693415
# differential_evolution step 90: f(x)= 5.799209884693415
# differential_evolution step 91: f(x)= 5.799209884693415
# differential_evolution step 92: f(x)= 5.799209884693415
# differential_evolution step 93: f(x)= 5.781807759428217
# differential_evolution step 94: f(x)= 5.781807759428217
# differential_evolution step 95: f(x)= 5.781807759428217
# differential_evolution step 96: f(x)= 5.781807759428217
# differential_evolution step 97: f(x)= 5.781807759428217
# differential_evolution step 98: f(x)= 5.781807759428217
# differential_evolution step 99: f(x)= 5.781807759428217
# differential_evolution step 100: f(x)= 5.781807759428217
# differential_evolution step 101: f(x)= 5.781807759428217
# differential_evolution step 102: f(x)= 5.781807759428217
# differential_evolution step 103: f(x)= 5.781807759428217
# differential_evolution step 104: f(x)= 5.781807759428217
# differential_evolution step 105: f(x)= 5.781807759428217
# differential_evolution step 106: f(x)= 5.781807759428217
# differential_evolution step 107: f(x)= 5.781807759428217
# differential_evolution step 108: f(x)= 5.781807759428217
# differential_evolution step 109: f(x)= 5.779641964191957
# differential_evolution step 110: f(x)= 5.779404306641767
# differential_evolution step 111: f(x)= 5.779404306641767
# differential_evolution step 112: f(x)= 5.779404306641767
# differential_evolution step 113: f(x)= 5.779404306641767
# differential_evolution step 114: f(x)= 5.779404306641767
# differential_evolution step 115: f(x)= 5.779404306641767
# differential_evolution step 116: f(x)= 5.779404306641767
# differential_evolution step 117: f(x)= 5.779404306641767
# differential_evolution step 118: f(x)= 5.779404306641767
# differential_evolution step 119: f(x)= 5.779404306641767
# differential_evolution step 120: f(x)= 5.779404306641767
# differential_evolution step 121: f(x)= 5.779404306641767
# differential_evolution step 122: f(x)= 5.779404306641767
# differential_evolution step 123: f(x)= 5.777808583948762
# differential_evolution step 124: f(x)= 5.777808583948762
# differential_evolution step 125: f(x)= 5.777808583948762
# differential_evolution step 126: f(x)= 5.777808583948762
# differential_evolution step 127: f(x)= 5.777808583948762
# differential_evolution step 128: f(x)= 5.776693686175927
# differential_evolution step 129: f(x)= 5.77618050365125
# differential_evolution step 130: f(x)= 5.77618050365125
# differential_evolution step 131: f(x)= 5.776024061189986
# differential_evolution step 132: f(x)= 5.775999241127601
# differential_evolution step 133: f(x)= 5.775999241127601
# differential_evolution step 134: f(x)= 5.7756035415695095
# differential_evolution step 135: f(x)= 5.7756035415695095
# differential_evolution step 136: f(x)= 5.775507540298459
# differential_evolution step 137: f(x)= 5.775507540298459
# differential_evolution step 138: f(x)= 5.775218432482338
# differential_evolution step 139: f(x)= 5.7744337269931165
# differential_evolution step 140: f(x)= 5.7744337269931165
# differential_evolution step 141: f(x)= 5.7744337269931165
# differential_evolution step 142: f(x)= 5.7744337269931165
# differential_evolution step 143: f(x)= 5.7744337269931165
# differential_evolution step 144: f(x)= 5.7744337269931165
# differential_evolution step 145: f(x)= 5.7744337269931165
# differential_evolution step 146: f(x)= 5.7744337269931165
# differential_evolution step 147: f(x)= 5.7744337269931165
# differential_evolution step 148: f(x)= 5.7744337269931165
# differential_evolution step 149: f(x)= 5.7744337269931165
# differential_evolution step 150: f(x)= 5.7744337269931165
# differential_evolution step 151: f(x)= 5.7744337269931165
# differential_evolution step 152: f(x)= 5.773992674522264
# differential_evolution step 153: f(x)= 5.773752246932957
# differential_evolution step 154: f(x)= 5.773752246932957
# differential_evolution step 155: f(x)= 5.773752246932957
# differential_evolution step 156: f(x)= 5.773752246932957
# differential_evolution step 157: f(x)= 5.773752246932957
# differential_evolution step 158: f(x)= 5.773752246932957
# differential_evolution step 159: f(x)= 5.773752246932957
# differential_evolution step 160: f(x)= 5.773752246932957
# differential_evolution step 161: f(x)= 5.773752246932957
# differential_evolution step 162: f(x)= 5.773752246932957
# differential_evolution step 163: f(x)= 5.773752246932957
# differential_evolution step 164: f(x)= 5.7735105898190415
# differential_evolution step 165: f(x)= 5.7735105898190415
# differential_evolution step 166: f(x)= 5.7735105898190415
# differential_evolution step 167: f(x)= 5.7735105898190415
# differential_evolution step 168: f(x)= 5.7735105898190415
# differential_evolution step 169: f(x)= 5.7735105898190415
# differential_evolution step 170: f(x)= 5.7735105898190415
# differential_evolution step 171: f(x)= 5.7735105898190415
# differential_evolution step 172: f(x)= 5.7735105898190415
# differential_evolution step 173: f(x)= 5.7735105898190415
# differential_evolution step 174: f(x)= 5.7735105898190415
# differential_evolution step 175: f(x)= 5.7735105898190415
# differential_evolution step 176: f(x)= 5.7735105898190415
# differential_evolution step 177: f(x)= 5.7735105898190415
# differential_evolution step 178: f(x)= 5.7735105898190415
# differential_evolution step 179: f(x)= 5.7735105898190415
# differential_evolution step 180: f(x)= 5.7735105898190415
# differential_evolution step 181: f(x)= 5.773482501774883
# differential_evolution step 182: f(x)= 5.773482501774883
# differential_evolution step 183: f(x)= 5.773482501774883
# differential_evolution step 184: f(x)= 5.773482501774883
# differential_evolution step 185: f(x)= 5.773482501774883
# differential_evolution step 186: f(x)= 5.773482501774883
# differential_evolution step 187: f(x)= 5.773482501774883
# differential_evolution step 188: f(x)= 5.773482501774883
# differential_evolution step 189: f(x)= 5.773482501774883
# differential_evolution step 190: f(x)= 5.773482501774883
# differential_evolution step 191: f(x)= 5.773482501774883
# differential_evolution step 192: f(x)= 5.773463292119248
# differential_evolution step 193: f(x)= 5.773463292119248
# differential_evolution step 194: f(x)= 5.773463292119248
# differential_evolution step 195: f(x)= 5.773463292119248
# differential_evolution step 196: f(x)= 5.773463292119248
# differential_evolution step 197: f(x)= 5.773463292119248
# differential_evolution step 198: f(x)= 5.773463292119248
# differential_evolution step 199: f(x)= 5.773329650283493
# differential_evolution step 200: f(x)= 5.773329650283493
# differential_evolution step 201: f(x)= 5.773329650283493
# differential_evolution step 202: f(x)= 5.773329650283493
# differential_evolution step 203: f(x)= 5.773329650283493
# differential_evolution step 204: f(x)= 5.773329650283493
# differential_evolution step 205: f(x)= 5.773329650283493
# differential_evolution step 206: f(x)= 5.773329650283493
# differential_evolution step 207: f(x)= 5.773329650283493
# differential_evolution step 208: f(x)= 5.773329650283493
# differential_evolution step 209: f(x)= 5.773329650283493
# differential_evolution step 210: f(x)= 5.773329650283493
# differential_evolution step 211: f(x)= 5.773329650283493
# differential_evolution step 212: f(x)= 5.773329650283493
# differential_evolution step 213: f(x)= 5.773329650283493
# differential_evolution step 214: f(x)= 5.773329650283493
# differential_evolution step 215: f(x)= 5.773329650283493
# differential_evolution step 216: f(x)= 5.773329650283493
# differential_evolution step 217: f(x)= 5.773329650283493
# differential_evolution step 218: f(x)= 5.773329650283493
# differential_evolution step 219: f(x)= 5.7732955483612844
# differential_evolution step 220: f(x)= 5.7732955483612844
# differential_evolution step 221: f(x)= 5.7732955483612844
# differential_evolution step 222: f(x)= 5.7732955483612844
# differential_evolution step 223: f(x)= 5.7732955483612844
# differential_evolution step 224: f(x)= 5.7732955483612844
# differential_evolution step 225: f(x)= 5.7732955483612844
# differential_evolution step 226: f(x)= 5.7732955483612844
# differential_evolution step 227: f(x)= 5.7732955483612844
# differential_evolution step 228: f(x)= 5.773275447946906
# differential_evolution step 229: f(x)= 5.773275447946906
# differential_evolution step 230: f(x)= 5.773275447946906
# differential_evolution step 231: f(x)= 5.773275447946906
# differential_evolution step 232: f(x)= 5.773275447946906
# differential_evolution step 233: f(x)= 5.773275447946906
# differential_evolution step 234: f(x)= 5.773275447946906
# differential_evolution step 235: f(x)= 5.773275447946906
# differential_evolution step 236: f(x)= 5.773275447946906
# differential_evolution step 237: f(x)= 5.773275447946906
# differential_evolution step 238: f(x)= 5.773275447946906
# differential_evolution step 239: f(x)= 5.773275447946906
# differential_evolution step 240: f(x)= 5.773275447946906
# differential_evolution step 241: f(x)= 5.773275447946906
# differential_evolution step 242: f(x)= 5.773275447946906
# differential_evolution step 243: f(x)= 5.773275447946906
# differential_evolution step 244: f(x)= 5.773275447946906
# differential_evolution step 245: f(x)= 5.773275447946906
# differential_evolution step 246: f(x)= 5.773275447946906
# differential_evolution step 247: f(x)= 5.773275447946906
# differential_evolution step 248: f(x)= 5.773275447946906
# differential_evolution step 249: f(x)= 5.773275447946906
# differential_evolution step 250: f(x)= 5.773275447946906
# differential_evolution step 251: f(x)= 5.773275447946906
# differential_evolution step 252: f(x)= 5.773275447946906
# differential_evolution step 253: f(x)= 5.773275447946906
# differential_evolution step 254: f(x)= 5.773275447946906
# differential_evolution step 255: f(x)= 5.773275447946906
# differential_evolution step 256: f(x)= 5.773275447946906
# differential_evolution step 257: f(x)= 5.773275447946906
# differential_evolution step 258: f(x)= 5.773273509303231
# differential_evolution step 259: f(x)= 5.773273509303231
# differential_evolution step 260: f(x)= 5.773273509303231
# differential_evolution step 261: f(x)= 5.773273509303231
# differential_evolution step 262: f(x)= 5.773256094154787
# differential_evolution step 263: f(x)= 5.773205736108008
# differential_evolution step 264: f(x)= 5.773205736108008
# differential_evolution step 265: f(x)= 5.773205736108008
# differential_evolution step 266: f(x)= 5.773205736108008
# differential_evolution step 267: f(x)= 5.773205736108008
# differential_evolution step 268: f(x)= 5.773205736108008
# differential_evolution step 269: f(x)= 5.773205736108008
# differential_evolution step 270: f(x)= 5.773205736108008
# differential_evolution step 271: f(x)= 5.773159608374719
# differential_evolution step 272: f(x)= 5.773159608374719
# differential_evolution step 273: f(x)= 5.773159608374719
# differential_evolution step 274: f(x)= 5.773159608374719
# differential_evolution step 275: f(x)= 5.773159608374719
# differential_evolution step 276: f(x)= 5.773159608374719
# differential_evolution step 277: f(x)= 5.773159608374719
# differential_evolution step 278: f(x)= 5.773159608374719
# differential_evolution step 279: f(x)= 5.773159608374719
# differential_evolution step 280: f(x)= 5.773159608374719
# differential_evolution step 281: f(x)= 5.773159608374719
# differential_evolution step 282: f(x)= 5.773159608374719
# differential_evolution step 283: f(x)= 5.773140911996155
# differential_evolution step 284: f(x)= 5.773140911996155
# differential_evolution step 285: f(x)= 5.7730880076412365
# differential_evolution step 286: f(x)= 5.7730880076412365
# differential_evolution step 287: f(x)= 5.7730880076412365
# differential_evolution step 288: f(x)= 5.7730880076412365
# differential_evolution step 289: f(x)= 5.7730880076412365
# differential_evolution step 290: f(x)= 5.7730880076412365
# differential_evolution step 291: f(x)= 5.7730880076412365
# differential_evolution step 292: f(x)= 5.7730880076412365
# differential_evolution step 293: f(x)= 5.7730880076412365
# differential_evolution step 294: f(x)= 5.7730880076412365
# differential_evolution step 295: f(x)= 5.7730880076412365
# differential_evolution step 296: f(x)= 5.7730880076412365
# differential_evolution step 297: f(x)= 5.7730880076412365
# differential_evolution step 298: f(x)= 5.7730880076412365
# differential_evolution step 299: f(x)= 5.7730880076412365
# differential_evolution step 300: f(x)= 5.7730880076412365
# differential_evolution step 301: f(x)= 5.7730880076412365
# differential_evolution step 302: f(x)= 5.7730880076412365
# differential_evolution step 303: f(x)= 5.7730880076412365
# differential_evolution step 304: f(x)= 5.7730880076412365
# differential_evolution step 305: f(x)= 5.7730880076412365
# differential_evolution step 306: f(x)= 5.7730880076412365
# differential_evolution step 307: f(x)= 5.7730880076412365
# differential_evolution step 308: f(x)= 5.7730880076412365
# differential_evolution step 309: f(x)= 5.7730880076412365
# differential_evolution step 310: f(x)= 5.7730880076412365
# differential_evolution step 311: f(x)= 5.7730880076412365
# differential_evolution step 312: f(x)= 5.7730880076412365
# differential_evolution step 313: f(x)= 5.7730880076412365
# differential_evolution step 314: f(x)= 5.7730880076412365
# differential_evolution step 315: f(x)= 5.7730880076412365
# differential_evolution step 316: f(x)= 5.7730880076412365
# differential_evolution step 317: f(x)= 5.773078144990563
# differential_evolution step 318: f(x)= 5.773078144990563
# differential_evolution step 319: f(x)= 5.773078144990563
# differential_evolution step 320: f(x)= 5.773078144990563
# differential_evolution step 321: f(x)= 5.773078144990563
# differential_evolution step 322: f(x)= 5.773078144990563
# differential_evolution step 323: f(x)= 5.773078144990563
# differential_evolution step 324: f(x)= 5.773078144990563
# differential_evolution step 325: f(x)= 5.773078144990563
# differential_evolution step 326: f(x)= 5.773078144990563
# differential_evolution step 327: f(x)= 5.773078144990563
# differential_evolution step 328: f(x)= 5.773078144990563
# differential_evolution step 329: f(x)= 5.773078144990563
# differential_evolution step 330: f(x)= 5.773078144990563
# differential_evolution step 331: f(x)= 5.773078144990563
# differential_evolution step 332: f(x)= 5.773078144990563
# differential_evolution step 333: f(x)= 5.773078144990563
# differential_evolution step 334: f(x)= 5.773078144990563
# differential_evolution step 335: f(x)= 5.773078144990563
# differential_evolution step 336: f(x)= 5.773078144990563
# differential_evolution step 337: f(x)= 5.773078144990563
# differential_evolution step 338: f(x)= 5.773078144990563
# differential_evolution step 339: f(x)= 5.773078144990563
# differential_evolution step 340: f(x)= 5.773078144990563
# differential_evolution step 341: f(x)= 5.773078144990563
# differential_evolution step 342: f(x)= 5.773078144990563
# differential_evolution step 343: f(x)= 5.773078144990563
# differential_evolution step 344: f(x)= 5.773078144990563
# differential_evolution step 345: f(x)= 5.773078144990563
# differential_evolution step 346: f(x)= 5.773078144990563
# differential_evolution step 347: f(x)= 5.773078144990563
# differential_evolution step 348: f(x)= 5.773078144990563
# differential_evolution step 349: f(x)= 5.773078144990563
# differential_evolution step 350: f(x)= 5.773078144990563
# differential_evolution step 351: f(x)= 5.773078144990563
# differential_evolution step 352: f(x)= 5.773078144990563
# differential_evolution step 353: f(x)= 5.773078144990563
# differential_evolution step 354: f(x)= 5.773078144990563
# differential_evolution step 355: f(x)= 5.773078144990563
# differential_evolution step 356: f(x)= 5.773078144990563
# differential_evolution step 357: f(x)= 5.773078144990563
# differential_evolution step 358: f(x)= 5.773078144990563
# differential_evolution step 359: f(x)= 5.773078144990563
# differential_evolution step 360: f(x)= 5.773078144990563
# differential_evolution step 361: f(x)= 5.773078144990563
# differential_evolution step 362: f(x)= 5.773078144990563
# differential_evolution step 363: f(x)= 5.773078144990563
# differential_evolution step 364: f(x)= 5.773078144990563
# differential_evolution step 365: f(x)= 5.77307087010418
# differential_evolution step 366: f(x)= 5.77307087010418
# differential_evolution step 367: f(x)= 5.77307087010418
# differential_evolution step 368: f(x)= 5.77307087010418
# differential_evolution step 369: f(x)= 5.77307087010418
# differential_evolution step 370: f(x)= 5.77307087010418
# differential_evolution step 371: f(x)= 5.77307087010418
# differential_evolution step 372: f(x)= 5.77307087010418
# differential_evolution step 373: f(x)= 5.77307087010418
# differential_evolution step 374: f(x)= 5.773070543838264
# differential_evolution step 375: f(x)= 5.773070543838264
# differential_evolution step 376: f(x)= 5.773070543838264
# differential_evolution step 377: f(x)= 5.773070543838264
# differential_evolution step 378: f(x)= 5.773070543838264
# differential_evolution step 379: f(x)= 5.773070543838264
# differential_evolution step 380: f(x)= 5.773070543838264
# differential_evolution step 381: f(x)= 5.773070543838264
# differential_evolution step 382: f(x)= 5.773063793169594
# differential_evolution step 383: f(x)= 5.773063793169594
# differential_evolution step 384: f(x)= 5.773063793169594
# differential_evolution step 385: f(x)= 5.773063793169594
# differential_evolution step 386: f(x)= 5.773044253767687
# differential_evolution step 387: f(x)= 5.773044253767687
# differential_evolution step 388: f(x)= 5.773044253767687
# differential_evolution step 389: f(x)= 5.773044253767687
# differential_evolution step 390: f(x)= 5.773044253767687
# differential_evolution step 391: f(x)= 5.773044253767687
# differential_evolution step 392: f(x)= 5.773044253767687
# differential_evolution step 393: f(x)= 5.773044253767687
# differential_evolution step 394: f(x)= 5.773044253767687
# differential_evolution step 395: f(x)= 5.773044253767687
# differential_evolution step 396: f(x)= 5.773044253767687
# differential_evolution step 397: f(x)= 5.773033775896697
# differential_evolution step 398: f(x)= 5.773033775896697
# differential_evolution step 399: f(x)= 5.773033775896697
# differential_evolution step 400: f(x)= 5.773033775896697
# differential_evolution step 401: f(x)= 5.773033775896697
# differential_evolution step 402: f(x)= 5.773033775896697
# differential_evolution step 403: f(x)= 5.773033775896697
# differential_evolution step 404: f(x)= 5.773033775896697
# differential_evolution step 405: f(x)= 5.773033775896697
# differential_evolution step 406: f(x)= 5.773033775896697
# differential_evolution step 407: f(x)= 5.773033775896697
# differential_evolution step 408: f(x)= 5.773033775896697
# differential_evolution step 409: f(x)= 5.773033775896697
# differential_evolution step 410: f(x)= 5.773033775896697
# differential_evolution step 411: f(x)= 5.773033775896697
# differential_evolution step 412: f(x)= 5.773033775896697
# differential_evolution step 413: f(x)= 5.773033775896697
# differential_evolution step 414: f(x)= 5.773033775896697
# differential_evolution step 415: f(x)= 5.773033775896697
# differential_evolution step 416: f(x)= 5.773033775896697
# differential_evolution step 417: f(x)= 5.773033775896697
# differential_evolution step 418: f(x)= 5.773033775896697
# differential_evolution step 419: f(x)= 5.773033775896697
# differential_evolution step 420: f(x)= 5.773033775896697
# differential_evolution step 421: f(x)= 5.773033775896697
# differential_evolution step 422: f(x)= 5.773033775896697
# differential_evolution step 423: f(x)= 5.773033775896697
# differential_evolution step 424: f(x)= 5.773033775896697
# differential_evolution step 425: f(x)= 5.773033775896697
# differential_evolution step 426: f(x)= 5.773033775896697
# differential_evolution step 427: f(x)= 5.773033775896697
# differential_evolution step 428: f(x)= 5.773033775896697
# differential_evolution step 429: f(x)= 5.773033775896697
# differential_evolution step 430: f(x)= 5.773033775896697
# differential_evolution step 431: f(x)= 5.773033775896697
# differential_evolution step 432: f(x)= 5.773033775896697
# differential_evolution step 433: f(x)= 5.773033775896697
# differential_evolution step 434: f(x)= 5.773033775896697
# differential_evolution step 435: f(x)= 5.773033775896697
# differential_evolution step 436: f(x)= 5.773033775896697
# differential_evolution step 437: f(x)= 5.773033775896697
# differential_evolution step 438: f(x)= 5.773033775896697
# differential_evolution step 439: f(x)= 5.773033775896697
# differential_evolution step 440: f(x)= 5.773033775896697
# differential_evolution step 441: f(x)= 5.773033775896697
# differential_evolution step 442: f(x)= 5.773033775896697
# differential_evolution step 443: f(x)= 5.773033775896697
# differential_evolution step 444: f(x)= 5.773033775896697
# differential_evolution step 445: f(x)= 5.773033775896697
# differential_evolution step 446: f(x)= 5.773033775896697
# differential_evolution step 447: f(x)= 5.773033775896697
# differential_evolution step 448: f(x)= 5.773033775896697
# differential_evolution step 449: f(x)= 5.773033775896697
# differential_evolution step 450: f(x)= 5.773033775896697
# differential_evolution step 451: f(x)= 5.773032913261082
# differential_evolution step 452: f(x)= 5.773032913261082
# differential_evolution step 453: f(x)= 5.773032913261082
# differential_evolution step 454: f(x)= 5.773032913261082
# differential_evolution step 455: f(x)= 5.773032913261082
# differential_evolution step 456: f(x)= 5.773032913261082
# differential_evolution step 457: f(x)= 5.773032913261082
# differential_evolution step 458: f(x)= 5.773032913261082
# differential_evolution step 459: f(x)= 5.773032913261082
# differential_evolution step 460: f(x)= 5.773032913261082
# differential_evolution step 461: f(x)= 5.773032913261082
# differential_evolution step 462: f(x)= 5.773032913261082
# differential_evolution step 463: f(x)= 5.773032913261082
# differential_evolution step 464: f(x)= 5.773032913261082
# differential_evolution step 465: f(x)= 5.773032913261082
# differential_evolution step 466: f(x)= 5.773032913261082
# differential_evolution step 467: f(x)= 5.773032913261082
# differential_evolution step 468: f(x)= 5.773032913261082
# differential_evolution step 469: f(x)= 5.773032913261082
# differential_evolution step 470: f(x)= 5.773032913261082
# differential_evolution step 471: f(x)= 5.773032913261082
# differential_evolution step 472: f(x)= 5.773032913261082
# differential_evolution step 473: f(x)= 5.773032913261082
# differential_evolution step 474: f(x)= 5.773032913261082
# differential_evolution step 475: f(x)= 5.773032913261082
# differential_evolution step 476: f(x)= 5.773032913261082
# differential_evolution step 477: f(x)= 5.773032913261082
# differential_evolution step 478: f(x)= 5.773032913261082
# differential_evolution step 479: f(x)= 5.773032913261082
# differential_evolution step 480: f(x)= 5.773032913261082
# differential_evolution step 481: f(x)= 5.773032913261082
# differential_evolution step 482: f(x)= 5.773032913261082
# differential_evolution step 483: f(x)= 5.773032913261082
# differential_evolution step 484: f(x)= 5.773032913261082
# differential_evolution step 485: f(x)= 5.773032913261082
# differential_evolution step 486: f(x)= 5.773032913261082
# differential_evolution step 487: f(x)= 5.773032913261082
# differential_evolution step 488: f(x)= 5.77302451097697
# differential_evolution step 489: f(x)= 5.77302451097697
# differential_evolution step 490: f(x)= 5.77302451097697
# differential_evolution step 491: f(x)= 5.77302451097697
# differential_evolution step 492: f(x)= 5.77302451097697
# differential_evolution step 493: f(x)= 5.77302451097697
# differential_evolution step 494: f(x)= 5.77302451097697
# differential_evolution step 495: f(x)= 5.77302451097697
# differential_evolution step 496: f(x)= 5.77302451097697
# differential_evolution step 497: f(x)= 5.77302451097697
# differential_evolution step 498: f(x)= 5.77302451097697
# differential_evolution step 499: f(x)= 5.77302451097697
# differential_evolution step 500: f(x)= 5.77302451097697
# differential_evolution step 501: f(x)= 5.77302451097697
# differential_evolution step 502: f(x)= 5.77302451097697
# differential_evolution step 503: f(x)= 5.77302451097697
# differential_evolution step 504: f(x)= 5.77302451097697
# differential_evolution step 505: f(x)= 5.77302451097697
# differential_evolution step 506: f(x)= 5.77302451097697
# differential_evolution step 507: f(x)= 5.77302451097697
# differential_evolution step 508: f(x)= 5.77302451097697
# differential_evolution step 509: f(x)= 5.77302451097697
# differential_evolution step 510: f(x)= 5.77302451097697
# differential_evolution step 511: f(x)= 5.77302451097697
# differential_evolution step 512: f(x)= 5.77302451097697
# differential_evolution step 513: f(x)= 5.77302451097697
# differential_evolution step 514: f(x)= 5.77302451097697
# differential_evolution step 515: f(x)= 5.77302451097697
# differential_evolution step 516: f(x)= 5.77302451097697
# differential_evolution step 517: f(x)= 5.77302451097697
# differential_evolution step 518: f(x)= 5.77302451097697
# differential_evolution step 519: f(x)= 5.77302451097697
# differential_evolution step 520: f(x)= 5.77302451097697
# differential_evolution step 521: f(x)= 5.77302451097697
# differential_evolution step 522: f(x)= 5.77302451097697
# differential_evolution step 523: f(x)= 5.773021975216688
# differential_evolution step 524: f(x)= 5.773021975216688
# differential_evolution step 525: f(x)= 5.773021975216688
# differential_evolution step 526: f(x)= 5.773021975216688
# differential_evolution step 527: f(x)= 5.773021975216688
# differential_evolution step 528: f(x)= 5.773021975216688
# differential_evolution step 529: f(x)= 5.773021975216688
# differential_evolution step 530: f(x)= 5.773021975216688
# differential_evolution step 531: f(x)= 5.773021975216688
# differential_evolution step 532: f(x)= 5.773021975216688
# differential_evolution step 533: f(x)= 5.773021975216688
# differential_evolution step 534: f(x)= 5.773021975216688
# differential_evolution step 535: f(x)= 5.773021975216688
# differential_evolution step 536: f(x)= 5.773021975216688
# differential_evolution step 537: f(x)= 5.773021975216688
# differential_evolution step 538: f(x)= 5.773021975216688
# differential_evolution step 539: f(x)= 5.773021975216688
# differential_evolution step 540: f(x)= 5.773021975216688
# differential_evolution step 541: f(x)= 5.773021975216688
# differential_evolution step 542: f(x)= 5.773021975216688
# differential_evolution step 543: f(x)= 5.773021975216688
# differential_evolution step 544: f(x)= 5.773021975216688
# differential_evolution step 545: f(x)= 5.773021975216688
# differential_evolution step 546: f(x)= 5.773021975216688
# differential_evolution step 547: f(x)= 5.773021975216688
# differential_evolution step 548: f(x)= 5.773021975216688
# differential_evolution step 549: f(x)= 5.773021975216688
# differential_evolution step 550: f(x)= 5.773021975216688
# differential_evolution step 551: f(x)= 5.773021975216688
# differential_evolution step 552: f(x)= 5.773021975216688
# differential_evolution step 553: f(x)= 5.773021975216688
# differential_evolution step 554: f(x)= 5.773021975216688
# differential_evolution step 555: f(x)= 5.773021975216688
# differential_evolution step 556: f(x)= 5.773007578590448
# differential_evolution step 557: f(x)= 5.773007578590448
# differential_evolution step 558: f(x)= 5.773007578590448
# differential_evolution step 559: f(x)= 5.773007578590448
# differential_evolution step 560: f(x)= 5.773007578590448
# differential_evolution step 561: f(x)= 5.773007578590448
# differential_evolution step 562: f(x)= 5.773007578590448
# differential_evolution step 563: f(x)= 5.773007578590448
# differential_evolution step 564: f(x)= 5.773007578590448
# differential_evolution step 565: f(x)= 5.773007578590448
# differential_evolution step 566: f(x)= 5.773007578590448
# differential_evolution step 567: f(x)= 5.773007578590448
# differential_evolution step 568: f(x)= 5.773007578590448
# differential_evolution step 569: f(x)= 5.773007578590448
# differential_evolution step 570: f(x)= 5.773007578590448
# differential_evolution step 571: f(x)= 5.77300428992518
# differential_evolution step 572: f(x)= 5.77300428992518
# differential_evolution step 573: f(x)= 5.77300428992518
# differential_evolution step 574: f(x)= 5.77300428992518
# differential_evolution step 575: f(x)= 5.77300428992518
# differential_evolution step 576: f(x)= 5.77300428992518
# differential_evolution step 577: f(x)= 5.77300428992518
# differential_evolution step 578: f(x)= 5.77300428992518
# differential_evolution step 579: f(x)= 5.77300428992518
# differential_evolution step 580: f(x)= 5.77300428992518
# differential_evolution step 581: f(x)= 5.77300428992518
# differential_evolution step 582: f(x)= 5.77300428992518
# differential_evolution step 583: f(x)= 5.77300428992518
# differential_evolution step 584: f(x)= 5.77300428992518
# differential_evolution step 585: f(x)= 5.77300428992518
# differential_evolution step 586: f(x)= 5.77300428992518
# differential_evolution step 587: f(x)= 5.77300428992518
# differential_evolution step 588: f(x)= 5.77300428992518
# differential_evolution step 589: f(x)= 5.77300428992518
# differential_evolution step 590: f(x)= 5.77300428992518
# differential_evolution step 591: f(x)= 5.77300428992518
# differential_evolution step 592: f(x)= 5.773000574573727
# differential_evolution step 593: f(x)= 5.773000574573727
# differential_evolution step 594: f(x)= 5.773000574573727
# differential_evolution step 595: f(x)= 5.773000574573727
# differential_evolution step 596: f(x)= 5.773000574573727
# differential_evolution step 597: f(x)= 5.773000574573727
# differential_evolution step 598: f(x)= 5.773000574573727
# differential_evolution step 599: f(x)= 5.773000574573727
# differential_evolution step 600: f(x)= 5.773000574573727
# differential_evolution step 601: f(x)= 5.773000574573727
# differential_evolution step 602: f(x)= 5.773000574573727
# differential_evolution step 603: f(x)= 5.773000574573727
# differential_evolution step 604: f(x)= 5.773000574573727
# differential_evolution step 605: f(x)= 5.773000574573727
# differential_evolution step 606: f(x)= 5.773000574573727
# differential_evolution step 607: f(x)= 5.773000574573727
# differential_evolution step 608: f(x)= 5.773000574573727
# differential_evolution step 609: f(x)= 5.773000574573727
# differential_evolution step 610: f(x)= 5.773000574573727
# differential_evolution step 611: f(x)= 5.773000574573727
# differential_evolution step 612: f(x)= 5.773000574573727
# differential_evolution step 613: f(x)= 5.773000574573727
# differential_evolution step 614: f(x)= 5.773000574573727
# differential_evolution step 615: f(x)= 5.773000574573727
# differential_evolution step 616: f(x)= 5.773000574573727
# differential_evolution step 617: f(x)= 5.773000574573727
# differential_evolution step 618: f(x)= 5.773000574573727
# differential_evolution step 619: f(x)= 5.773000574573727
# differential_evolution step 620: f(x)= 5.773000574573727
# differential_evolution step 621: f(x)= 5.773000574573727
# differential_evolution step 622: f(x)= 5.773000574573727
# differential_evolution step 623: f(x)= 5.773000574573727
# differential_evolution step 624: f(x)= 5.773000574573727
# differential_evolution step 625: f(x)= 5.773000574573727
# differential_evolution step 626: f(x)= 5.773000574573727
# differential_evolution step 627: f(x)= 5.772998129002961
# differential_evolution step 628: f(x)= 5.772998129002961
# differential_evolution step 629: f(x)= 5.772998129002961
# differential_evolution step 630: f(x)= 5.772998129002961
# differential_evolution step 631: f(x)= 5.772998129002961
# differential_evolution step 632: f(x)= 5.772998129002961
# differential_evolution step 633: f(x)= 5.772998129002961
# differential_evolution step 634: f(x)= 5.772998129002961
# differential_evolution step 635: f(x)= 5.772998129002961
# differential_evolution step 636: f(x)= 5.772998129002961
# differential_evolution step 637: f(x)= 5.772998129002961
# differential_evolution step 638: f(x)= 5.772998129002961
# differential_evolution step 639: f(x)= 5.772998129002961
# differential_evolution step 640: f(x)= 5.772998129002961
# differential_evolution step 641: f(x)= 5.772998129002961
# differential_evolution step 642: f(x)= 5.772998129002961
# differential_evolution step 643: f(x)= 5.772998129002961
# differential_evolution step 644: f(x)= 5.772998129002961
# differential_evolution step 645: f(x)= 5.772998129002961
# differential_evolution step 646: f(x)= 5.772998129002961
# differential_evolution step 647: f(x)= 5.772998129002961
# differential_evolution step 648: f(x)= 5.772998129002961
# differential_evolution step 649: f(x)= 5.772998129002961
# differential_evolution step 650: f(x)= 5.772998129002961
# differential_evolution step 651: f(x)= 5.772998129002961
# differential_evolution step 652: f(x)= 5.772998129002961
# differential_evolution step 653: f(x)= 5.772998129002961
# differential_evolution step 654: f(x)= 5.772998129002961
# differential_evolution step 655: f(x)= 5.772998129002961
# differential_evolution step 656: f(x)= 5.772998129002961

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic[1] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params2)
chi_quadr[1] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params2)
bic[1] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params2)
print(aic[1], chi_quadr[1], bic[1], len(best_params2))

dof_HA = len(radial_profile_HA) - len(best_params2)
print('Reduced chi square:', chi_quadr[1] / dof_HA)
red_chi[1] = chi_quadr[1] / dof_HA
plt.savefig('AIC_2')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20)   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (18, 23),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (28, 36)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic[2] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params3)
chi_quadr[2] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params3)
bic[2] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params3)
print(aic[2], chi_quadr[2], bic[2], len(best_params3))

dof_HA = len(radial_profile_HA) - len(best_params3)
print('Reduced chi square:', chi_quadr[2] / dof_HA)
red_chi[2] = chi_quadr[2] / dof_HA
plt.savefig('AIC_3')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20)   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (18, 23),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (28, 36),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (67, 74),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic[3] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params4)
chi_quadr[3] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params4)
bic[3] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params4)
print(aic[3], chi_quadr[3], bic[3], len(best_params4))

dof_HA = len(radial_profile_HA) - len(best_params4)
print('Reduced chi square:', chi_quadr[3] / dof_HA)
red_chi[3] = chi_quadr[3] / dof_HA
plt.savefig('AIC_4')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20)   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (18, 23),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (28, 36),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (67, 74),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic[4] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params5)
chi_quadr[4] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params5)
bic[4] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params5)
print(aic[4], chi_quadr[4], bic[4], len(best_params5))

dof_HA = len(radial_profile_HA) - len(best_params5)
print('Reduced chi square:', chi_quadr[4] / dof_HA)
red_chi[4] = chi_quadr[4] / dof_HA
plt.savefig('AIC_5')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
   (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (14, 20)   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (18, 23),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (28, 36),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (67, 74),     # x_0: posizione da 0 a 100
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 120)
y_fit = model_convolved(xgrid, *best_params6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *best_params6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
ax[1].set_ylim(-0.2, 0.2)

aic[5] = AIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params6)
chi_quadr[5] = chi_quad(x_axes, radial_profile_HA, radial_profile_error_HA, best_params6)
bic[5] = BIC(x_axes, radial_profile_HA, radial_profile_error_HA, best_params6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

dof_HA = len(radial_profile_HA) - len(best_params6)
print('Reduced chi square:', chi_quadr[5] / dof_HA)
red_chi[5] = chi_quadr[5] / dof_HA
plt.savefig('AIC_6')

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N')

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log')
