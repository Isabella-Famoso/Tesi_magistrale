# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_17.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_17']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [ 0.01756548  0.00982952  0.02141064 ...  0.00579824 -0.00174287
#   0.00516969] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.8752; DOF: 1944; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.2860; DOF: 1921; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 20., 180.])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -492        86
#  comp.  1:        20       180
#  comp.  2:       -54         1
# chi2/DOF: 1.485; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.962       1.4     -54     1
# Comp:  2             [SII]6731      3.829       1.4     -54     1
# Comp:  2              HeII4687     0.1127       1.4     -54     1
# Comp:  2               HeI5876      1.146       1.4     -54     1
# Comp:  2          [OIII]5007_d      1.515       1.8     -54     1
# Comp:  2            [OI]6300_d      2.358       1.8     -54     1
# Comp:  2           [NII]6583_d      1.580       1.8     -54     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   1.29; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.389; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.07661; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  0.782; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.7766; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.143; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  0.753; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -470        22
#  comp.  1:       -23         1
#  comp.  2:       -60         1
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.4     -23     1
# Comp:  1                Halpha      1.937       1.4     -23     1
# Comp:  2             [SII]6716      1.952       1.4     -60     1
# Comp:  2             [SII]6731      3.484       1.4     -60     1
# Comp:  2              HeII4687      0.000       1.4     -60     1
# Comp:  2               HeI5876     0.1693       1.4     -60     1
# Comp:  2          [OIII]5007_d      0.000       1.8     -60     1
# Comp:  2            [OI]6300_d      2.771       1.8     -60     1
# Comp:  2           [NII]6583_d      1.075       1.8     -60     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -493        90
#  comp.  1:        93         1
#  comp.  2:       -50         1
# chi2/DOF: 1.473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.316       1.4      93     1
# Comp:  1                Halpha     0.6269       1.4      93     1
# Comp:  2             [SII]6716      1.915       1.4     -50     1
# Comp:  2             [SII]6731      3.895       1.4     -50     1
# Comp:  2              HeII4687      0.000       1.4     -50     1
# Comp:  2               HeI5876     0.9863       1.4     -50     1
# Comp:  2          [OIII]5007_d      3.357       1.8     -50     1
# Comp:  2            [OI]6300_d      1.816       1.8     -50     1
# Comp:  2           [NII]6583_d      1.535       1.8     -50     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -425       222
#  comp.  1:      -464       516
#  comp.  2:       -51         1
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.68       4.0    -464   516
# Comp:  1                Halpha      16.04       4.1    -464   516
# Comp:  2             [SII]6716      1.878       1.4     -51     1
# Comp:  2             [SII]6731      3.830       1.4     -51     1
# Comp:  2              HeII4687     0.2085       1.4     -51     1
# Comp:  2               HeI5876      1.695       1.4     -51     1
# Comp:  2          [OIII]5007_d      1.935       1.8     -51     1
# Comp:  2            [OI]6300_d      2.550       1.8     -51     1
# Comp:  2           [NII]6583_d      2.069       1.8     -51     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -486        88
#  comp.  1:        20       180
#  comp.  2:       -52        95
# chi2/DOF: 1.472; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.778       1.9     -52    95
# Comp:  2             [SII]6731      4.442       1.9     -52    95
# Comp:  2              HeII4687      2.974       1.9     -52    95
# Comp:  2               HeI5876      2.252       1.9     -52    95
# Comp:  2          [OIII]5007_d      0.000       2.4     -52    95
# Comp:  2            [OI]6300_d      4.185       2.4     -52    95
# Comp:  2           [NII]6583_d      4.232       2.4     -52    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -525       144
#  comp.  1:        44       119
#  comp.  2:       -55         1
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9564       2.0      44   119
# Comp:  1                Halpha    0.03787       2.0      44   119
# Comp:  2             [SII]6716      1.723       1.4     -55     1
# Comp:  2             [SII]6731      3.734       1.4     -55     1
# Comp:  2              HeII4687      0.000       1.4     -55     1
# Comp:  2               HeI5876      2.388       1.4     -55     1
# Comp:  2          [OIII]5007_d      1.324       1.8     -55     1
# Comp:  2            [OI]6300_d      2.990       1.8     -55     1
# Comp:  2           [NII]6583_d      1.503       1.8     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -479       111
#  comp.  1:        -9       187
#  comp.  2:       -53       112
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.326       2.5      -9   187
# Comp:  1                Halpha     0.6527       2.5      -9   187
# Comp:  2             [SII]6716      2.719       2.0     -53   112
# Comp:  2             [SII]6731      5.725       2.0     -53   112
# Comp:  2              HeII4687      0.000       2.0     -53   112
# Comp:  2               HeI5876     0.9179       2.0     -53   112
# Comp:  2          [OIII]5007_d     0.7949       2.5     -53   112
# Comp:  2            [OI]6300_d      4.450       2.5     -53   112
# Comp:  2           [NII]6583_d      1.419       2.5     -53   112
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -548       120
#  comp.  1:        20       180
#  comp.  2:       -39        58
# chi2/DOF: 1.477; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.998       1.6     -39    58
# Comp:  2             [SII]6731      4.325       1.6     -39    58
# Comp:  2              HeII4687      1.142       1.6     -39    58
# Comp:  2               HeI5876      1.661       1.6     -39    58
# Comp:  2          [OIII]5007_d      1.627       2.1     -39    58
# Comp:  2            [OI]6300_d      2.427       2.1     -39    58
# Comp:  2           [NII]6583_d      1.681       2.1     -39    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -490        91
#  comp.  1:        27       171
#  comp.  2:       -53        35
# chi2/DOF: 1.473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.257       2.4      27   171
# Comp:  1                Halpha      0.000       2.4      27   171
# Comp:  2             [SII]6716      2.210       1.5     -53    35
# Comp:  2             [SII]6731      4.271       1.5     -53    35
# Comp:  2              HeII4687      0.000       1.5     -53    35
# Comp:  2               HeI5876      2.504       1.5     -53    35
# Comp:  2          [OIII]5007_d     0.6366       1.9     -53    35
# Comp:  2            [OI]6300_d      2.464       1.9     -53    35
# Comp:  2           [NII]6583_d      2.120       1.9     -53    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -553        79
#  comp.  1:       131         1
#  comp.  2:       -17       101
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.276       1.4     131     1
# Comp:  1                Halpha     0.5057       1.4     131     1
# Comp:  2             [SII]6716      2.609       1.9     -17   101
# Comp:  2             [SII]6731      4.923       1.9     -17   101
# Comp:  2              HeII4687      0.000       1.9     -17   101
# Comp:  2               HeI5876      5.526       1.9     -17   101
# Comp:  2          [OIII]5007_d      2.543       2.4     -17   101
# Comp:  2            [OI]6300_d      2.845       2.4     -17   101
# Comp:  2           [NII]6583_d      2.941       2.4     -17   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -516       141
#  comp.  1:       -39       235
#  comp.  2:       -46        41
# chi2/DOF: 1.475; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.7     -39   235
# Comp:  1                Halpha      3.565       2.7     -39   235
# Comp:  2             [SII]6716      2.035       1.5     -46    41
# Comp:  2             [SII]6731      3.590       1.5     -46    41
# Comp:  2              HeII4687      0.000       1.5     -46    41
# Comp:  2               HeI5876      1.504       1.5     -46    41
# Comp:  2          [OIII]5007_d      2.034       2.0     -46    41
# Comp:  2            [OI]6300_d      2.698       2.0     -46    41
# Comp:  2           [NII]6583_d      1.459       2.0     -46    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -507        43
#  comp.  1:       144       129
#  comp.  2:       -63         1
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.1     144   129
# Comp:  1                Halpha      1.887       2.1     144   129
# Comp:  2             [SII]6716      1.937       1.4     -63     1
# Comp:  2             [SII]6731      3.192       1.4     -63     1
# Comp:  2              HeII4687    0.09528       1.4     -63     1
# Comp:  2               HeI5876     0.4870       1.4     -63     1
# Comp:  2          [OIII]5007_d      2.052       1.8     -63     1
# Comp:  2            [OI]6300_d      3.095       1.8     -63     1
# Comp:  2           [NII]6583_d      2.419       1.8     -63     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -510         1
#  comp.  1:       137         1
#  comp.  2:       -57         1
# chi2/DOF: 1.473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.447       1.4     137     1
# Comp:  1                Halpha      0.000       1.4     137     1
# Comp:  2             [SII]6716      1.884       1.4     -57     1
# Comp:  2             [SII]6731      3.832       1.4     -57     1
# Comp:  2              HeII4687      0.000       1.4     -57     1
# Comp:  2               HeI5876      0.000       1.4     -57     1
# Comp:  2          [OIII]5007_d      2.608       1.8     -57     1
# Comp:  2            [OI]6300_d      2.371       1.8     -57     1
# Comp:  2           [NII]6583_d      1.022       1.8     -57     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -514       244
#  comp.  1:      2020      1000
#  comp.  2:       -51         1
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.164       5.6    2020  1000
# Comp:  1                Halpha      0.000       5.7    2020  1000
# Comp:  2             [SII]6716      2.061       1.4     -51     1
# Comp:  2             [SII]6731      3.713       1.4     -51     1
# Comp:  2              HeII4687    0.07210       1.4     -51     1
# Comp:  2               HeI5876     0.8994       1.4     -51     1
# Comp:  2          [OIII]5007_d      2.303       1.8     -51     1
# Comp:  2            [OI]6300_d      2.291       1.8     -51     1
# Comp:  2           [NII]6583_d      1.459       1.8     -51     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -429       176
#  comp.  1:        90       185
#  comp.  2:       -46        14
# chi2/DOF: 1.473; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.956       2.5      90   185
# Comp:  1                Halpha      0.000       2.5      90   185
# Comp:  2             [SII]6716      1.664       1.4     -46    14
# Comp:  2             [SII]6731      3.317       1.4     -46    14
# Comp:  2              HeII4687     0.5963       1.4     -46    14
# Comp:  2               HeI5876      0.000       1.4     -46    14
# Comp:  2          [OIII]5007_d      1.737       1.8     -46    14
# Comp:  2            [OI]6300_d      1.998       1.8     -46    14
# Comp:  2           [NII]6583_d     0.5860       1.8     -46    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -461         1
#  comp.  1:        20       180
#  comp.  2:       -37        46
# chi2/DOF: 1.479; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.266       1.6     -37    46
# Comp:  2             [SII]6731      3.690       1.6     -37    46
# Comp:  2              HeII4687      1.499       1.6     -37    46
# Comp:  2               HeI5876      0.000       1.6     -37    46
# Comp:  2          [OIII]5007_d      2.242       2.0     -37    46
# Comp:  2            [OI]6300_d      2.875       2.0     -37    46
# Comp:  2           [NII]6583_d      2.597       2.0     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -274       249
#  comp.  1:      -260       446
#  comp.  2:        96       430
# chi2/DOF: 1.469; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.87       3.7    -260   446
# Comp:  1                Halpha      17.47       4.0    -260   446
# Comp:  2             [SII]6716      6.059       4.5      96   430
# Comp:  2             [SII]6731      4.991       4.5      96   430
# Comp:  2              HeII4687    0.09214       3.7      96   430
# Comp:  2               HeI5876      11.94       3.7      96   430
# Comp:  2          [OIII]5007_d      0.000       4.6      96   430
# Comp:  2            [OI]6300_d      2.289       4.6      96   430
# Comp:  2           [NII]6583_d     0.2580       5.0      96   430
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -444         5
#  comp.  1:       154       232
#  comp.  2:       -60        60
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6891       2.7     154   232
# Comp:  1                Halpha     0.1321       2.7     154   232
# Comp:  2             [SII]6716      2.586       1.7     -60    60
# Comp:  2             [SII]6731      5.125       1.7     -60    60
# Comp:  2              HeII4687      0.000       1.7     -60    60
# Comp:  2               HeI5876      0.000       1.7     -60    60
# Comp:  2          [OIII]5007_d     0.2948       2.1     -60    60
# Comp:  2            [OI]6300_d      2.125       2.1     -60    60
# Comp:  2           [NII]6583_d      2.027       2.1     -60    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -496        40
#  comp.  1:        93       282
#  comp.  2:       -46         1
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.508       3.0      93   282
# Comp:  1                Halpha     0.4952       3.0      93   282
# Comp:  2             [SII]6716      1.875       1.4     -46     1
# Comp:  2             [SII]6731      4.278       1.4     -46     1
# Comp:  2              HeII4687     0.1090       1.4     -46     1
# Comp:  2               HeI5876     0.5035       1.4     -46     1
# Comp:  2          [OIII]5007_d      0.000       1.8     -46     1
# Comp:  2            [OI]6300_d      2.669       1.8     -46     1
# Comp:  2           [NII]6583_d      2.694       1.8     -46     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -479        66
#  comp.  1:         5       130
#  comp.  2:       -51         1
# chi2/DOF: 1.476; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.056       2.1       5   130
# Comp:  1                Halpha      2.574       2.1       5   130
# Comp:  2             [SII]6716      1.925       1.4     -51     1
# Comp:  2             [SII]6731      3.126       1.4     -51     1
# Comp:  2              HeII4687      0.000       1.4     -51     1
# Comp:  2               HeI5876      0.000       1.4     -51     1
# Comp:  2          [OIII]5007_d     0.6326       1.8     -51     1
# Comp:  2            [OI]6300_d      2.299       1.8     -51     1
# Comp:  2           [NII]6583_d      1.517       1.8     -51     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -358         1
#  comp.  1:       946       926
#  comp.  2:       -32         1
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.95       5.3     946   926
# Comp:  1                Halpha     0.2746       5.8     946   926
# Comp:  2             [SII]6716      1.953       1.4     -32     1
# Comp:  2             [SII]6731      3.977       1.4     -32     1
# Comp:  2              HeII4687      0.000       1.4     -32     1
# Comp:  2               HeI5876      1.491       1.4     -32     1
# Comp:  2          [OIII]5007_d      1.398       1.8     -32     1
# Comp:  2            [OI]6300_d      2.200       1.8     -32     1
# Comp:  2           [NII]6583_d      2.019       2.0     -32     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -449        87
#  comp.  1:      -439       491
#  comp.  2:       -59         1
# chi2/DOF: 1.477; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      28.76       3.9    -439   491
# Comp:  1                Halpha      12.35       4.0    -439   491
# Comp:  2             [SII]6716      1.878       1.4     -59     1
# Comp:  2             [SII]6731      3.251       1.4     -59     1
# Comp:  2              HeII4687      0.000       1.4     -59     1
# Comp:  2               HeI5876      0.000       1.4     -59     1
# Comp:  2          [OIII]5007_d      2.060       1.8     -59     1
# Comp:  2            [OI]6300_d      2.027       1.8     -59     1
# Comp:  2           [NII]6583_d     0.2862       1.8     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -483       180
#  comp.  1:        20       180
#  comp.  2:       -68         1
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1527       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.188       1.4     -68     1
# Comp:  2             [SII]6731      3.911       1.4     -68     1
# Comp:  2              HeII4687      0.000       1.4     -68     1
# Comp:  2               HeI5876      1.315       1.4     -68     1
# Comp:  2          [OIII]5007_d      0.000       1.8     -68     1
# Comp:  2            [OI]6300_d      1.988       1.8     -68     1
# Comp:  2           [NII]6583_d      1.403       1.8     -68     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -357       152
#  comp.  1:      -290       147
#  comp.  2:       -23        58
# chi2/DOF: 1.467; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.574       2.2    -290   147
# Comp:  1                Halpha      4.979       2.2    -290   147
# Comp:  2             [SII]6716      2.251       1.6     -23    58
# Comp:  2             [SII]6731      3.936       1.6     -23    58
# Comp:  2              HeII4687      1.389       1.6     -23    58
# Comp:  2               HeI5876      3.890       1.6     -23    58
# Comp:  2          [OIII]5007_d      1.876       2.1     -23    58
# Comp:  2            [OI]6300_d      1.778       2.1     -23    58
# Comp:  2           [NII]6583_d      1.034       2.1     -23    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -513        90
#  comp.  1:       -86       413
#  comp.  2:       -70         1
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.250       3.6     -86   413
# Comp:  1                Halpha      1.239       3.6     -86   413
# Comp:  2             [SII]6716      1.908       1.4     -70     1
# Comp:  2             [SII]6731      4.153       1.4     -70     1
# Comp:  2              HeII4687      1.740       1.4     -70     1
# Comp:  2               HeI5876      1.927       1.4     -70     1
# Comp:  2          [OIII]5007_d      3.477       1.8     -70     1
# Comp:  2            [OI]6300_d      2.093       1.8     -70     1
# Comp:  2           [NII]6583_d      2.193       1.8     -70     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -490        90
#  comp.  1:        27       188
#  comp.  2:       -53        31
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.878       2.5      27   188
# Comp:  1                Halpha      0.000       2.5      27   188
# Comp:  2             [SII]6716      2.344       1.5     -53    31
# Comp:  2             [SII]6731      4.264       1.5     -53    31
# Comp:  2              HeII4687      1.822       1.5     -53    31
# Comp:  2               HeI5876      3.091       1.5     -53    31
# Comp:  2          [OIII]5007_d      1.676       1.9     -53    31
# Comp:  2            [OI]6300_d      2.926       1.9     -53    31
# Comp:  2           [NII]6583_d      2.329       1.9     -53    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -464        85
#  comp.  1:       575       704
#  comp.  2:       -75        65
# chi2/DOF: 1.477; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.16       4.7     575   704
# Comp:  1                Halpha      7.318       5.3     575   704
# Comp:  2             [SII]6716      2.579       1.7     -75    65
# Comp:  2             [SII]6731      4.548       1.7     -75    65
# Comp:  2              HeII4687      1.860       1.7     -75    65
# Comp:  2               HeI5876      1.390       1.7     -75    65
# Comp:  2          [OIII]5007_d      3.711       2.1     -75    65
# Comp:  2            [OI]6300_d      2.757       2.1     -75    65
# Comp:  2           [NII]6583_d      0.000       2.4     -75    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -611         2
#  comp.  1:        32       145
#  comp.  2:       -59         1
# chi2/DOF: 1.472; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.2      32   145
# Comp:  1                Halpha      0.000       2.2      32   145
# Comp:  2             [SII]6716      1.907       1.4     -59     1
# Comp:  2             [SII]6731      3.616       1.4     -59     1
# Comp:  2              HeII4687      0.000       1.4     -59     1
# Comp:  2               HeI5876      2.010       1.4     -59     1
# Comp:  2          [OIII]5007_d     0.5506       1.8     -59     1
# Comp:  2            [OI]6300_d      2.148       1.8     -59     1
# Comp:  2           [NII]6583_d      1.537       1.8     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -459         1
#  comp.  1:        20       180
#  comp.  2:       -65         1
# chi2/DOF: 1.478; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.961       1.4     -65     1
# Comp:  2             [SII]6731      4.184       1.4     -65     1
# Comp:  2              HeII4687    0.03049       1.4     -65     1
# Comp:  2               HeI5876      1.083       1.4     -65     1
# Comp:  2          [OIII]5007_d      1.259       1.8     -65     1
# Comp:  2            [OI]6300_d      2.028       1.8     -65     1
# Comp:  2           [NII]6583_d      2.471       1.8     -65     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -547         1
#  comp.  1:        20       180
#  comp.  2:       -55        38
# chi2/DOF: 1.478; DOF: 2232; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.133       1.5     -55    38
# Comp:  2             [SII]6731      4.870       1.5     -55    38
# Comp:  2              HeII4687     0.8142       1.5     -55    38
# Comp:  2               HeI5876     0.8250       1.5     -55    38
# Comp:  2          [OIII]5007_d      1.119       1.9     -55    38
# Comp:  2            [OI]6300_d      2.686       1.9     -55    38
# Comp:  2           [NII]6583_d      1.480       1.9     -55    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -704       293
#  comp.  1:      -732       555
#  comp.  2:       -64        47
# chi2/DOF: 1.475; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      54.04       4.1    -732   555
# Comp:  1                Halpha      11.40       4.2    -732   555
# Comp:  2             [SII]6716      1.910       1.6     -64    47
# Comp:  2             [SII]6731      4.137       1.6     -64    47
# Comp:  2              HeII4687      0.000       1.6     -64    47
# Comp:  2               HeI5876      3.117       1.6     -64    47
# Comp:  2          [OIII]5007_d      3.489       2.0     -64    47
# Comp:  2            [OI]6300_d      2.307       2.0     -64    47
# Comp:  2           [NII]6583_d      2.592       2.0     -64    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       360
#  comp.  1:      -167       691
#  comp.  2:       -55         1
# chi2/DOF: 1.468; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.24       4.6    -167   691
# Comp:  1                Halpha      13.77       4.8    -167   691
# Comp:  2             [SII]6716      1.994       1.4     -55     1
# Comp:  2             [SII]6731      4.020       1.4     -55     1
# Comp:  2              HeII4687      1.284       1.4     -55     1
# Comp:  2               HeI5876      1.982       1.4     -55     1
# Comp:  2          [OIII]5007_d      2.225       1.8     -55     1
# Comp:  2            [OI]6300_d      2.211       1.8     -55     1
# Comp:  2           [NII]6583_d      1.944       1.9     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -448       115
#  comp.  1:     -1915        96
#  comp.  2:       -53         1
# chi2/DOF: 1.477; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.576       1.9   -1915    96
# Comp:  1                Halpha      0.000       1.9   -1915    96
# Comp:  2             [SII]6716      2.159       1.4     -53     1
# Comp:  2             [SII]6731      4.258       1.4     -53     1
# Comp:  2              HeII4687     0.4183       1.4     -53     1
# Comp:  2               HeI5876      1.342       1.4     -53     1
# Comp:  2          [OIII]5007_d      2.550       1.8     -53     1
# Comp:  2            [OI]6300_d      2.193       1.8     -53     1
# Comp:  2           [NII]6583_d     0.5943       1.8     -53     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -438        80
#  comp.  1:        20       180
#  comp.  2:       -58         1
# chi2/DOF: 1.468; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.727       1.4     -58     1
# Comp:  2             [SII]6731      3.987       1.4     -58     1
# Comp:  2              HeII4687      0.000       1.4     -58     1
# Comp:  2               HeI5876      2.611       1.4     -58     1
# Comp:  2          [OIII]5007_d     0.1358       1.8     -58     1
# Comp:  2            [OI]6300_d      2.247       1.8     -58     1
# Comp:  2           [NII]6583_d      2.374       1.8     -58     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -502        86
#  comp.  1:         7       213
#  comp.  2:       -55        23
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 13; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.6       7   213
# Comp:  1                Halpha      1.524       2.6       7   213
# Comp:  2             [SII]6716      2.126       1.5     -55    23
# Comp:  2             [SII]6731      4.416       1.5     -55    23
# Comp:  2              HeII4687      0.000       1.5     -55    23
# Comp:  2               HeI5876     0.8069       1.5     -55    23
# Comp:  2          [OIII]5007_d      2.908       1.9     -55    23
# Comp:  2            [OI]6300_d      2.182       1.9     -55    23
# Comp:  2           [NII]6583_d      3.320       1.9     -55    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -495        13
#  comp.  1:       -96        45
#  comp.  2:       -40        29
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6     -96    45
# Comp:  1                Halpha      1.564       1.6     -96    45
# Comp:  2             [SII]6716      1.883       1.5     -40    29
# Comp:  2             [SII]6731      3.788       1.5     -40    29
# Comp:  2              HeII4687      0.000       1.5     -40    29
# Comp:  2               HeI5876     0.9748       1.5     -40    29
# Comp:  2          [OIII]5007_d      1.697       1.9     -40    29
# Comp:  2            [OI]6300_d      1.558       1.9     -40    29
# Comp:  2           [NII]6583_d     0.9208       1.9     -40    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -500        98
#  comp.  1:        -8       212
#  comp.  2:       -53        49
# chi2/DOF: 1.482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 13; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7811       2.6      -8   212
# Comp:  1                Halpha     0.5922       2.6      -8   212
# Comp:  2             [SII]6716      2.006       1.6     -53    49
# Comp:  2             [SII]6731      5.016       1.6     -53    49
# Comp:  2              HeII4687   0.007428       1.6     -53    49
# Comp:  2               HeI5876      0.000       1.6     -53    49
# Comp:  2          [OIII]5007_d      3.027       2.0     -53    49
# Comp:  2            [OI]6300_d      2.426       2.0     -53    49
# Comp:  2           [NII]6583_d      1.428       2.0     -53    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -495        90
#  comp.  1:        15       169
#  comp.  2:       -53        23
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.529       2.4      15   169
# Comp:  1                Halpha     0.3700       2.4      15   169
# Comp:  2             [SII]6716      2.103       1.5     -53    23
# Comp:  2             [SII]6731      4.459       1.5     -53    23
# Comp:  2              HeII4687      1.207       1.5     -53    23
# Comp:  2               HeI5876      2.676       1.5     -53    23
# Comp:  2          [OIII]5007_d      0.000       1.9     -53    23
# Comp:  2            [OI]6300_d      2.322       1.9     -53    23
# Comp:  2           [NII]6583_d     0.8915       1.9     -53    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -673       337
#  comp.  1:        20       180
#  comp.  2:       -50         1
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.886       1.4     -50     1
# Comp:  2             [SII]6731      4.031       1.4     -50     1
# Comp:  2              HeII4687     0.3133       1.4     -50     1
# Comp:  2               HeI5876     0.6935       1.4     -50     1
# Comp:  2          [OIII]5007_d      2.569       1.8     -50     1
# Comp:  2            [OI]6300_d      2.734       1.8     -50     1
# Comp:  2           [NII]6583_d      0.000       1.8     -50     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -513        80
#  comp.  1:        39       351
#  comp.  2:       -72         1
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.732       3.3      39   351
# Comp:  1                Halpha      2.447       3.3      39   351
# Comp:  2             [SII]6716      2.105       1.4     -72     1
# Comp:  2             [SII]6731      3.645       1.4     -72     1
# Comp:  2              HeII4687     0.8433       1.4     -72     1
# Comp:  2               HeI5876      0.000       1.4     -72     1
# Comp:  2          [OIII]5007_d     0.8109       1.8     -72     1
# Comp:  2            [OI]6300_d      2.438       1.8     -72     1
# Comp:  2           [NII]6583_d      2.422       1.8     -72     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -487        90
#  comp.  1:        20      1000
#  comp.  2:       -54        23
# chi2/DOF: 1.482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.005       5.6      20  1000
# Comp:  1                Halpha     0.2075       5.9      20  1000
# Comp:  2             [SII]6716      2.004       1.5     -54    23
# Comp:  2             [SII]6731      4.511       1.5     -54    23
# Comp:  2              HeII4687     0.4898       1.5     -54    23
# Comp:  2               HeI5876      1.796       1.5     -54    23
# Comp:  2          [OIII]5007_d      2.408       1.9     -54    23
# Comp:  2            [OI]6300_d      2.353       1.9     -54    23
# Comp:  2           [NII]6583_d     0.5615       2.0     -54    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -421       105
#  comp.  1:      -131        79
#  comp.  2:       -54         1
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.541       1.8    -131    79
# Comp:  1                Halpha      1.988       1.8    -131    79
# Comp:  2             [SII]6716      2.070       1.4     -54     1
# Comp:  2             [SII]6731      4.518       1.4     -54     1
# Comp:  2              HeII4687     0.4427       1.4     -54     1
# Comp:  2               HeI5876      1.196       1.4     -54     1
# Comp:  2          [OIII]5007_d      1.934       1.8     -54     1
# Comp:  2            [OI]6300_d      1.665       1.8     -54     1
# Comp:  2           [NII]6583_d      1.311       1.8     -54     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -495        82
#  comp.  1:        20       180
#  comp.  2:       -54        70
# chi2/DOF: 1.477; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.639       1.7     -54    70
# Comp:  2             [SII]6731      4.485       1.7     -54    70
# Comp:  2              HeII4687     0.5064       1.7     -54    70
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.099       1.4      70     1
# Comp:  1                Halpha      0.000       1.4      70     1
# Comp:  2             [SII]6716      2.107       1.4     -59     1
# Comp:  2             [SII]6731      3.883       1.4     -59     1
# Comp:  2              HeII4687     0.2900       1.4     -59     1
# Comp:  2               HeI5876      1.205       1.4     -59     1
# Comp:  2          [OIII]5007_d     0.2547       1.8     -59     1
# Comp:  2            [OI]6300_d      2.566       1.8     -59     1
# Comp:  2           [NII]6583_d      0.000       1.8     -59     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -662        98
#  comp.  1:        51       110
#  comp.  2:       -52         7
# chi2/DOF: 1.470; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.123       2.0      51   110
# Comp:  1                Halpha      1.512       2.0      51   110
# Comp:  2             [SII]6716      1.740       1.4     -52     7
# Comp:  2             [SII]6731      3.489       1.4     -52     7
# Comp:  2              HeII4687     0.2731       1.4     -52     7
# Comp:  2               HeI5876      0.000       1.4     -52     7
# Comp:  2          [OIII]5007_d      3.965       1.8     -52     7
# Comp:  2            [OI]6300_d      2.697       1.8     -52     7
# Comp:  2           [NII]6583_d      2.542       1.8     -52     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -326        94
#  comp.  1:       -13       135
#  comp.  2:       -47         1
# chi2/DOF: 1.480; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.2     -13   135
# Comp:  1                Halpha      1.907       2.2     -13   135
# Comp:  2             [SII]6716      2.147       1.4     -47     1
# Comp:  2             [SII]6731      3.334       1.4     -47     1
# Comp:  2              HeII4687      1.085       1.4     -47     1
# Comp:  2               HeI5876      1.884       1.4     -47     1
# Comp:  2          [OIII]5007_d      0.000       1.8     -47     1
# Comp:  2            [OI]6300_d      1.988       1.8     -47     1
# Comp:  2           [NII]6583_d     0.5118       1.8     -47     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -530       127
#  comp.  1:       -37        37
#  comp.  2:       -47        44
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5     -37    37
# Comp:  1                Halpha      2.021       1.5     -37    37
# Comp:  2             [SII]6716      2.377       1.6     -47    44
# Comp:  2             [SII]6731      3.820       1.6     -47    44
# Comp:  2              HeII4687      1.459       1.6     -47    44
# Comp:  2               HeI5876      2.024       1.6     -47    44
# Comp:  2          [OIII]5007_d      3.022       2.0     -47    44
# Comp:  2            [OI]6300_d      1.668       2.0     -47    44
# Comp:  2           [NII]6583_d      1.535       2.0     -47    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -509         1
#  comp.  1:        20       180
#  comp.  2:      -340       375
# chi2/DOF: 1.479; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.6      20   180
# Comp:  2             [SII]6716      0.000       3.9    -340   375
# Comp:  2             [SII]6731      6.101       3.9    -340   375
# Comp:  2              HeII4687      0.000       3.4    -340   375
# Comp:  2               HeI5876      1.600       3.4    -340   375
# Comp:  2          [OIII]5007_d     0.1215       4.3    -340   375
# Comp:  2            [OI]6300_d      15.71       4.3    -340   375
# Comp:  2           [NII]6583_d      5.716       4.6    -340   375
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -558        95
#  comp.  1:      2020      1000
#  comp.  2:       -54        41
# chi2/DOF: 1.479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.063       5.6    2020  1000
# Comp:  1                Halpha      0.000       5.7    2020  1000
# Comp:  2             [SII]6716      2.046       1.5     -54    41
# Comp:  2             [SII]6731      3.671       1.5     -54    41
# Comp:  2              HeII4687      1.742       1.5     -54    41
# Comp:  2               HeI5876      2.885       1.5     -54    41
# Comp:  2          [OIII]5007_d      2.202       2.0     -54    41
# Comp:  2            [OI]6300_d      2.655       2.0     -54    41
# Comp:  2           [NII]6583_d      2.669       2.0     -54    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -499        68
#  comp.  1:        20       180
#  comp.  2:       -53        44
# chi2/DOF: 1.480; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.344       1.6     -53    44
# Comp:  2             [SII]6731      4.820       1.6     -53    44
# Comp:  2              HeII4687     0.7537       1.6     -53    44
# Comp:  2               HeI5876      1.989       1.6     -53    44
# Comp:  2          [OIII]5007_d      3.579       2.0     -53    44
# Comp:  2            [OI]6300_d      2.380       2.0     -53    44
# Comp:  2           [NII]6583_d      2.621       2.0     -53    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -553         1
#  comp.  1:       145         1
#  comp.  2:       -50        18
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.235       1.4     145     1
# Comp:  1                Halpha      0.000       1.4     145     1
# Comp:  2             [SII]6716      2.228       1.5     -50    18
# Comp:  2             [SII]6731      3.732       1.5     -50    18
# Comp:  2              HeII4687      0.000       1.5     -50    18
# Comp:  2               HeI5876     0.5282       1.5     -50    18
# Comp:  2          [OIII]5007_d     0.6069       1.8     -50    18
# Comp:  2            [OI]6300_d      2.989       1.8     -50    18
# Comp:  2           [NII]6583_d     0.9297       1.8     -50    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -487        85
#  comp.  1:        20       180
#  comp.  2:       -53        50
# chi2/DOF: 1.482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      2.215       1.6     -53    50
# Comp:  2             [SII]6731      4.024       1.6     -53    50
# Comp:  2              HeII4687      1.644       1.6     -53    50
# Comp:  2               HeI5876      0.000       1.6     -53    50
# Comp:  2          [OIII]5007_d     0.8095       2.0     -53    50
# Comp:  2            [OI]6300_d      2.014       2.0     -53    50
# Comp:  2           [NII]6583_d      3.653       2.0     -53    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -596       158
#  comp.  1:     -1948      1000
#  comp.  2:       -46         1
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       5.6   -1948  1000
# Comp:  1                Halpha      2.914       5.6   -1948  1000
# Comp:  2             [SII]6716      1.851       1.4     -46     1
# Comp:  2             [SII]6731      3.863       1.4     -46     1
# Comp:  2              HeII4687     0.6072       1.4     -46     1
# Comp:  2               HeI5876      1.132       1.4     -46     1
# Comp:  2          [OIII]5007_d     0.4188       1.8     -46     1
# Comp:  2            [OI]6300_d      2.489       1.8     -46     1
# Comp:  2           [NII]6583_d     0.6971       1.8     -46     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -492        86
#  comp.  1:        20       180
#  comp.  2:       -54         1
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.520       2.4      20   180
# Comp:  1                Halpha      0.000       2.4      20   180
# Comp:  2             [SII]6716      1.656       1.4     -54     1
# Comp:  2             [SII]6731      4.048       1.4     -54     1
# Comp:  2              HeII4687     0.8773       1.4     -54     1
# Comp:  2               HeI5876     0.9737       1.4     -54     1
# Comp:  2          [OIII]5007_d      2.325       1.8     -54     1
# Comp:  2            [OI]6300_d      2.293       1.8     -54     1
# Comp:  2           [NII]6583_d     0.9081       1.8     -54     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -494        94
#  comp.  1:        30       168
#  comp.  2:       -54        23
# chi2/DOF: 1.481; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       2.4      30   168
# Comp:  1                Halpha      1.059       2.4      30   168
# Comp:  2             [SII]6716      2.267       1.5     -54    23
# Comp:  2             [SII]6731      4.628       1.5     -54    23
# Comp:  2              HeII4687      0.000       1.5     -54    23
# Comp:  2               HeI5876      0.000       1.5     -54    23
# Comp:  2          [OIII]5007_d      1.816       1.9     -54    23
# Comp:  2            [OI]6300_d      2.423       1.9     -54    23
# Comp:  2           [NII]6583_d      2.758       1.9     -54    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -628        74
#  comp.  1:      -101       108
#  comp.  2:       -46         3
# chi2/DOF: 1.478; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.044       2.0    -101   108
# Comp:  1                Halpha      2.431       2.0    -101   108
# Comp:  2             [SII]6716      1.841       1.4     -46     3
# Comp:  2             [SII]6731      4.128       1.4     -46     3
# Comp:  2              HeII4687      1.026       1.4     -46     3
# Comp:  2               HeI5876      1.546       1.4     -46     3
# Comp:  2          [OIII]5007_d      3.109       1.8     -46     3
# Comp:  2            [OI]6300_d      2.794       1.8     -46     3
# Comp:  2           [NII]6583_d      2.345       1.8     -46     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -752        93
#  comp.  1:        24        15
#  comp.  2:       -35         1
# chi2/DOF: 1.469; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.057       1.4      24    15
# Comp:  1                Halpha      1.498       1.4      24    15
# Comp:  2             [SII]6716      1.930       1.4     -35     1
# Comp:  2             [SII]6731      3.616       1.4     -35     1
# Comp:  2              HeII4687      1.193       1.4     -35     1
# Comp:  2               HeI5876      2.544       1.4     -35     1
# Comp:  2          [OIII]5007_d      2.599       1.8     -35     1
# Comp:  2            [OI]6300_d      3.461       1.8     -35     1
# Comp:  2           [NII]6583_d      1.913       1.8     -35     1
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([8.59370694, 4.04915827, 0.73048477, 1.14052842, 1.42968019,
#        2.13821633, 1.38356258, 2.10968394, 1.50223622])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.        , 0.        , 2.74880976, 5.3757951 , 0.11014339,
#        1.4045513 , 1.58246706, 3.09831853, 2.1694783 ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_17_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_17", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_17_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_17_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_17_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.000000    0.070085
# 1        Halpha  0.000000    0.033022
# 2     [SII]6716  0.022418    0.005957
# 3     [SII]6731  0.043841    0.009301
# 4      HeII4687  0.000898    0.011660
# 5       HeI5876  0.011455    0.017438
# 6  [OIII]5007_d  0.012906    0.011283
# 7    [OI]6300_d  0.025268    0.017205
# 8   [NII]6583_d  0.017693    0.012251
#           Name      Flux  Error_flux
# 0        Hbeta  0.000000    0.070085
# 1       Halpha  0.000000    0.033022
# 2    [SII]6716  0.022418    0.005957
# 3    [SII]6731  0.043841    0.009301
# 4     HeII4687  0.000898    0.011660
# 5      HeI5876  0.011455    0.017438
# 6   [OIII]4959  0.003226    0.011283
# 7   [OIII]5007  0.009679    0.011283
# 8     [OI]6300  0.018951    0.017205
# 9     [OI]6364  0.006317    0.017205
# 10   [NII]6548  0.004423    0.012251
# 11   [NII]6583  0.013270    0.012251

# %%
np.median(flux_rf_rebin)
# Out:
# 0.008155349187417187
