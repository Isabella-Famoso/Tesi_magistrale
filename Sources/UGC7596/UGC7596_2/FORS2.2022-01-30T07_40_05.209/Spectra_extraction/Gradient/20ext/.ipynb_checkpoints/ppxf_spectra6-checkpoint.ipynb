# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_6.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_6']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.03860475 0.02566723 0.03122137 ... 0.02187441 0.01529087 0.00873407] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
# chi2/DOF: 0.08558; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
# chi2/DOF: 0.04720; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-81.51185095,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:        41        25
#  comp.  2:       575       323
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      41    25
# Comp:  1                Halpha      1.410      0.55      41    25
# Comp:  2             [SII]6716    0.01255       1.3     575   323
# Comp:  2             [SII]6731     0.1740       1.3     575   323
# Comp:  2              HeII4687      1.095       1.2     575   323
# Comp:  2               HeI5876      3.513       1.2     575   323
# Comp:  2          [OIII]5007_d      0.000       1.5     575   323
# Comp:  2            [OI]6300_d     0.7781       1.5     575   323
# Comp:  2           [NII]6583_d     0.1557       1.5     575   323
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  2.222; gas flux:      2 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.00426; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.05901; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.3723; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.194; gas flux:      4 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.1986; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.03965; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        36
#  comp.  1:        39        25
#  comp.  2:       586       308
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      39    25
# Comp:  1                Halpha      1.375      0.55      39    25
# Comp:  2             [SII]6716      0.000       1.2     586   308
# Comp:  2             [SII]6731      0.000       1.2     586   308
# Comp:  2              HeII4687      1.754       1.1     586   308
# Comp:  2               HeI5876      2.832       1.1     586   308
# Comp:  2          [OIII]5007_d      1.437       1.4     586   308
# Comp:  2            [OI]6300_d      1.959       1.4     586   308
# Comp:  2           [NII]6583_d     0.8788       1.5     586   308
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        76
#  comp.  1:        48        40
#  comp.  2:       491       149
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.387      0.57      48    40
# Comp:  1                Halpha      1.724      0.57      48    40
# Comp:  2             [SII]6716      0.000      0.82     491   149
# Comp:  2             [SII]6731     0.1970      0.82     491   149
# Comp:  2              HeII4687     0.5971      0.82     491   149
# Comp:  2               HeI5876      2.256      0.82     491   149
# Comp:  2          [OIII]5007_d      2.331       1.0     491   149
# Comp:  2            [OI]6300_d     0.1672       1.0     491   149
# Comp:  2           [NII]6583_d      1.680       1.0     491   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        15
#  comp.  1:        41        26
#  comp.  2:       577       320
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      41    26
# Comp:  1                Halpha      1.643      0.55      41    26
# Comp:  2             [SII]6716      1.609       1.3     577   320
# Comp:  2             [SII]6731      0.000       1.3     577   320
# Comp:  2              HeII4687      1.170       1.2     577   320
# Comp:  2               HeI5876      2.629       1.2     577   320
# Comp:  2          [OIII]5007_d      0.000       1.5     577   320
# Comp:  2            [OI]6300_d      0.000       1.5     577   320
# Comp:  2           [NII]6583_d      0.000       1.5     577   320
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:        53        30
#  comp.  2:       652       345
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1383      0.55      53    30
# Comp:  1                Halpha      1.507      0.56      53    30
# Comp:  2             [SII]6716     0.2191       1.3     652   345
# Comp:  2             [SII]6731     0.7919       1.3     652   345
# Comp:  2              HeII4687     0.6545       1.2     652   345
# Comp:  2               HeI5876      3.764       1.2     652   345
# Comp:  2          [OIII]5007_d      1.964       1.5     652   345
# Comp:  2            [OI]6300_d      2.376       1.5     652   345
# Comp:  2           [NII]6583_d     0.4119       1.6     652   345
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        40
#  comp.  1:        38        74
#  comp.  2:       630       411
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.09603      0.64      38    74
# Comp:  1                Halpha      2.199      0.66      38    74
# Comp:  2             [SII]6716      1.080       1.6     630   411
# Comp:  2             [SII]6731     0.7426       1.6     630   411
# Comp:  2              HeII4687      3.394       1.3     630   411
# Comp:  2               HeI5876      4.492       1.3     630   411
# Comp:  2          [OIII]5007_d      0.000       1.7     630   411
# Comp:  2            [OI]6300_d     0.2167       1.7     630   411
# Comp:  2           [NII]6583_d      0.000       1.7     630   411
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        36
#  comp.  1:       -13        77
#  comp.  2:       478       335
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.015      0.65     -13    77
# Comp:  1                Halpha      2.256      0.66     -13    77
# Comp:  2             [SII]6716      0.000       1.3     478   335
# Comp:  2             [SII]6731    0.08653       1.3     478   335
# Comp:  2              HeII4687      2.125       1.2     478   335
# Comp:  2               HeI5876      4.176       1.2     478   335
# Comp:  2          [OIII]5007_d      1.516       1.5     478   335
# Comp:  2            [OI]6300_d      0.000       1.5     478   335
# Comp:  2           [NII]6583_d     0.2840       1.5     478   335
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       154
#  comp.  1:        49        41
#  comp.  2:       777       341
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.09431      0.57      49    41
# Comp:  1                Halpha      1.936      0.58      49    41
# Comp:  2             [SII]6716      0.000       1.3     777   341
# Comp:  2             [SII]6731     0.9178       1.3     777   341
# Comp:  2              HeII4687     0.3894       1.2     777   341
# Comp:  2               HeI5876      5.305       1.2     777   341
# Comp:  2          [OIII]5007_d      0.000       1.5     777   341
# Comp:  2            [OI]6300_d      1.374       1.5     777   341
# Comp:  2           [NII]6583_d     0.2287       1.5     777   341
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        18
#  comp.  1:        41        24
#  comp.  2:       572       320
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3262      0.54      41    24
# Comp:  1                Halpha      1.248      0.55      41    24
# Comp:  2             [SII]6716      0.000       1.3     572   320
# Comp:  2             [SII]6731     0.4083       1.3     572   320
# Comp:  2              HeII4687     0.5229       1.2     572   320
# Comp:  2               HeI5876      3.210       1.2     572   320
# Comp:  2          [OIII]5007_d     0.3533       1.5     572   320
# Comp:  2            [OI]6300_d      0.000       1.5     572   320
# Comp:  2           [NII]6583_d      0.000       1.5     572   320
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        75
#  comp.  1:        38        30
#  comp.  2:       567       312
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.55      38    30
# Comp:  1                Halpha      1.670      0.56      38    30
# Comp:  2             [SII]6716      1.615       1.2     567   312
# Comp:  2             [SII]6731      0.000       1.2     567   312
# Comp:  2              HeII4687     0.3267       1.2     567   312
# Comp:  2               HeI5876      2.812       1.2     567   312
# Comp:  2          [OIII]5007_d     0.2743       1.5     567   312
# Comp:  2            [OI]6300_d     0.4898       1.5     567   312
# Comp:  2           [NII]6583_d     0.8724       1.5     567   312
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        63        40
#  comp.  2:       339       191
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.57      63    40
# Comp:  1                Halpha      1.436      0.57      63    40
# Comp:  2             [SII]6716     0.4898      0.92     339   191
# Comp:  2             [SII]6731      0.000      0.92     339   191
# Comp:  2              HeII4687     0.8142      0.92     339   191
# Comp:  2               HeI5876     0.7201      0.92     339   191
# Comp:  2          [OIII]5007_d      3.830       1.2     339   191
# Comp:  2            [OI]6300_d      1.007       1.2     339   191
# Comp:  2           [NII]6583_d     0.5602       1.2     339   191
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        21
#  comp.  1:        58        27
#  comp.  2:       526       372
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.55      58    27
# Comp:  1                Halpha      1.451      0.55      58    27
# Comp:  2             [SII]6716     0.3612       1.4     526   372
# Comp:  2             [SII]6731     0.7444       1.4     526   372
# Comp:  2              HeII4687     0.5832       1.3     526   372
# Comp:  2               HeI5876      3.860       1.3     526   372
# Comp:  2          [OIII]5007_d      0.000       1.6     526   372
# Comp:  2            [OI]6300_d     0.2874       1.6     526   372
# Comp:  2           [NII]6583_d      0.000       1.6     526   372
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90         1
#  comp.  1:        51         1
#  comp.  2:       660       204
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.52      51     1
# Comp:  1                Halpha      1.072      0.54      51     1
# Comp:  2             [SII]6716     0.8064      0.95     660   204
# Comp:  2             [SII]6731    0.01858      0.95     660   204
# Comp:  2              HeII4687      1.102      0.94     660   204
# Comp:  2               HeI5876      3.252      0.94     660   204
# Comp:  2          [OIII]5007_d      0.000       1.2     660   204
# Comp:  2            [OI]6300_d      1.403       1.2     660   204
# Comp:  2           [NII]6583_d      1.168       1.2     660   204
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        19
#  comp.  1:        40        25
#  comp.  2:       579       333
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5065      0.54      40    25
# Comp:  1                Halpha      1.328      0.55      40    25
# Comp:  2             [SII]6716      0.000       1.3     579   333
# Comp:  2             [SII]6731      0.000       1.3     579   333
# Comp:  2              HeII4687      2.121       1.2     579   333
# Comp:  2               HeI5876      2.843       1.2     579   333
# Comp:  2          [OIII]5007_d     0.2438       1.5     579   333
# Comp:  2            [OI]6300_d     0.2786       1.5     579   333
# Comp:  2           [NII]6583_d      0.000       1.5     579   333
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:        23        64
#  comp.  2:       550       257
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3086      0.62      23    64
# Comp:  1                Halpha      2.393      0.63      23    64
# Comp:  2             [SII]6716     0.8469       1.1     550   257
# Comp:  2             [SII]6731     0.9309       1.1     550   257
# Comp:  2              HeII4687    0.04373       1.1     550   257
# Comp:  2               HeI5876      2.483       1.1     550   257
# Comp:  2          [OIII]5007_d      0.000       1.3     550   257
# Comp:  2            [OI]6300_d     0.1011       1.3     550   257
# Comp:  2           [NII]6583_d     0.3926       1.4     550   257
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:        37        12
#  comp.  2:       621       190
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.53      37    12
# Comp:  1                Halpha      1.130      0.54      37    12
# Comp:  2             [SII]6716     0.1615      0.92     621   190
# Comp:  2             [SII]6731     0.6039      0.92     621   190
# Comp:  2              HeII4687      1.322      0.92     621   190
# Comp:  2               HeI5876      3.464      0.92     621   190
# Comp:  2          [OIII]5007_d      1.507       1.2     621   190
# Comp:  2            [OI]6300_d      1.951       1.2     621   190
# Comp:  2           [NII]6583_d      1.350       1.2     621   190
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:        34        22
#  comp.  2:       544       323
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      34    22
# Comp:  1                Halpha      1.373      0.55      34    22
# Comp:  2             [SII]6716      1.638       1.3     544   323
# Comp:  2             [SII]6731      0.000       1.3     544   323
# Comp:  2              HeII4687     0.7277       1.2     544   323
# Comp:  2               HeI5876      3.042       1.2     544   323
# Comp:  2          [OIII]5007_d    0.04866       1.5     544   323
# Comp:  2            [OI]6300_d      1.867       1.5     544   323
# Comp:  2           [NII]6583_d     0.6700       1.5     544   323
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        51        14
#  comp.  2:       586       226
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5061      0.53      51    14
# Comp:  1                Halpha      1.376      0.54      51    14
# Comp:  2             [SII]6716      2.103       1.0     586   226
# Comp:  2             [SII]6731      0.000       1.0     586   226
# Comp:  2              HeII4687      1.259      0.99     586   226
# Comp:  2               HeI5876      4.248      0.99     586   226
# Comp:  2          [OIII]5007_d     0.1089       1.3     586   226
# Comp:  2            [OI]6300_d     0.7571       1.3     586   226
# Comp:  2           [NII]6583_d      0.000       1.3     586   226
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:        38        49
#  comp.  2:       458        57
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.59      38    49
# Comp:  1                Halpha      1.488      0.59      38    49
# Comp:  2             [SII]6716      0.000      0.60     458    57
# Comp:  2             [SII]6731      0.000      0.60     458    57
# Comp:  2              HeII4687     0.4352      0.60     458    57
# Comp:  2               HeI5876      1.224      0.60     458    57
# Comp:  2          [OIII]5007_d      3.218      0.76     458    57
# Comp:  2            [OI]6300_d     0.8293      0.76     458    57
# Comp:  2           [NII]6583_d      0.000      0.76     458    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        35        30
#  comp.  2:       594       150
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.05898      0.55      35    30
# Comp:  1                Halpha      1.383      0.56      35    30
# Comp:  2             [SII]6716      0.000      0.83     594   150
# Comp:  2             [SII]6731     0.4662      0.83     594   150
# Comp:  2              HeII4687     0.8192      0.83     594   150
# Comp:  2               HeI5876      2.021      0.83     594   150
# Comp:  2          [OIII]5007_d      0.000       1.0     594   150
# Comp:  2            [OI]6300_d      0.000       1.0     594   150
# Comp:  2           [NII]6583_d      0.000       1.1     594   150
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:        61        31
#  comp.  2:       519        93
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.55      61    31
# Comp:  1                Halpha      1.435      0.55      61    31
# Comp:  2             [SII]6716      0.000      0.69     519    93
# Comp:  2             [SII]6731     0.1750      0.69     519    93
# Comp:  2              HeII4687     0.4775      0.69     519    93
# Comp:  2               HeI5876      2.023      0.69     519    93
# Comp:  2          [OIII]5007_d      3.351      0.87     519    93
# Comp:  2            [OI]6300_d     0.4905      0.87     519    93
# Comp:  2           [NII]6583_d     0.6266      0.87     519    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        53        35
#  comp.  2:       575       281
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.56      53    35
# Comp:  1                Halpha      1.412      0.57      53    35
# Comp:  2             [SII]6716      0.000       1.1     575   281
# Comp:  2             [SII]6731     0.1334       1.1     575   281
# Comp:  2              HeII4687     0.9553       1.1     575   281
# Comp:  2               HeI5876      2.577       1.1     575   281
# Comp:  2          [OIII]5007_d      1.348       1.4     575   281
# Comp:  2            [OI]6300_d      2.320       1.4     575   281
# Comp:  2           [NII]6583_d      0.000       1.4     575   281
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:        53         1
#  comp.  2:       585       241
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1712      0.52      53     1
# Comp:  1                Halpha      1.294      0.53      53     1
# Comp:  2             [SII]6716      1.098       1.0     585   241
# Comp:  2             [SII]6731     0.2905       1.0     585   241
# Comp:  2              HeII4687     0.3144       1.0     585   241
# Comp:  2               HeI5876      2.201       1.0     585   241
# Comp:  2          [OIII]5007_d    0.09820       1.3     585   241
# Comp:  2            [OI]6300_d     0.3207       1.3     585   241
# Comp:  2           [NII]6583_d      0.000       1.3     585   241
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:        25         1
#  comp.  2:       642       215
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5377      0.52      25     1
# Comp:  1                Halpha      1.449      0.54      25     1
# Comp:  2             [SII]6716     0.1603      0.98     642   215
# Comp:  2             [SII]6731      0.000      0.98     642   215
# Comp:  2              HeII4687     0.6299      0.97     642   215
# Comp:  2               HeI5876      4.091      0.97     642   215
# Comp:  2          [OIII]5007_d      0.000       1.2     642   215
# Comp:  2            [OI]6300_d      0.000       1.2     642   215
# Comp:  2           [NII]6583_d      1.987       1.3     642   215
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13       105
#  comp.  1:        64        38
#  comp.  2:       539       266
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.56      64    38
# Comp:  1                Halpha      1.933      0.57      64    38
# Comp:  2             [SII]6716     0.9497       1.1     539   266
# Comp:  2             [SII]6731    0.04951       1.1     539   266
# Comp:  2              HeII4687      1.008       1.1     539   266
# Comp:  2               HeI5876      3.784       1.1     539   266
# Comp:  2          [OIII]5007_d      0.000       1.3     539   266
# Comp:  2            [OI]6300_d     0.3114       1.3     539   266
# Comp:  2           [NII]6583_d      0.000       1.4     539   266
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        83
#  comp.  1:        41        26
#  comp.  2:       578       328
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1263      0.54      41    26
# Comp:  1                Halpha      1.632      0.55      41    26
# Comp:  2             [SII]6716      0.000       1.3     578   328
# Comp:  2             [SII]6731     0.3063       1.3     578   328
# Comp:  2              HeII4687     0.9245       1.2     578   328
# Comp:  2               HeI5876      4.387       1.2     578   328
# Comp:  2          [OIII]5007_d      0.000       1.5     578   328
# Comp:  2            [OI]6300_d     0.4501       1.5     578   328
# Comp:  2           [NII]6583_d     0.1760       1.5     578   328
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:        44        35
#  comp.  2:       579       410
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1560      0.56      44    35
# Comp:  1                Halpha      1.383      0.57      44    35
# Comp:  2             [SII]6716     0.3746       1.6     579   410
# Comp:  2             [SII]6731      1.109       1.6     579   410
# Comp:  2              HeII4687      2.683       1.3     579   410
# Comp:  2               HeI5876      4.133       1.3     579   410
# Comp:  2          [OIII]5007_d      1.241       1.7     579   410
# Comp:  2            [OI]6300_d     0.4537       1.7     579   410
# Comp:  2           [NII]6583_d      0.000       1.7     579   410
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        34        32
#  comp.  2:       534       320
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.55      34    32
# Comp:  1                Halpha      1.734      0.56      34    32
# Comp:  2             [SII]6716     0.7516       1.3     534   320
# Comp:  2             [SII]6731      1.039       1.3     534   320
# Comp:  2              HeII4687     0.8000       1.2     534   320
# Comp:  2               HeI5876      4.783       1.2     534   320
# Comp:  2          [OIII]5007_d      0.000       1.5     534   320
# Comp:  2            [OI]6300_d      3.785       1.5     534   320
# Comp:  2           [NII]6583_d     0.6574       1.5     534   320
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        45
#  comp.  1:        41        27
#  comp.  2:       574       321
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.070      0.54      41    27
# Comp:  1                Halpha      1.508      0.55      41    27
# Comp:  2             [SII]6716      1.206       1.3     574   321
# Comp:  2             [SII]6731      0.000       1.3     574   321
# Comp:  2              HeII4687      1.644       1.2     574   321
# Comp:  2               HeI5876      2.187       1.2     574   321
# Comp:  2          [OIII]5007_d      0.000       1.5     574   321
# Comp:  2            [OI]6300_d      2.058       1.5     574   321
# Comp:  2           [NII]6583_d      2.619       1.5     574   321
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        27
#  comp.  1:        44         1
#  comp.  2:       617       313
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8289      0.52      44     1
# Comp:  1                Halpha      1.383      0.53      44     1
# Comp:  2             [SII]6716     0.8870       1.2     617   313
# Comp:  2             [SII]6731      0.000       1.2     617   313
# Comp:  2              HeII4687      2.812       1.2     617   313
# Comp:  2               HeI5876      3.204       1.2     617   313
# Comp:  2          [OIII]5007_d      5.130       1.5     617   313
# Comp:  2            [OI]6300_d      1.174       1.5     617   313
# Comp:  2           [NII]6583_d      1.222       1.5     617   313
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:        46        30
#  comp.  2:       628       328
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.55      46    30
# Comp:  1                Halpha      1.507      0.56      46    30
# Comp:  2             [SII]6716      0.000       1.3     628   328
# Comp:  2             [SII]6731      0.000       1.3     628   328
# Comp:  2              HeII4687      2.040       1.2     628   328
# Comp:  2               HeI5876      2.143       1.2     628   328
# Comp:  2          [OIII]5007_d     0.9849       1.5     628   328
# Comp:  2            [OI]6300_d      1.964       1.5     628   328
# Comp:  2           [NII]6583_d      0.000       1.5     628   328
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:        30        27
#  comp.  2:       767       574
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9482      0.55      30    27
# Comp:  1                Halpha      1.661      0.55      30    27
# Comp:  2             [SII]6716     0.9018       2.3     767   574
# Comp:  2             [SII]6731      0.000       2.3     767   574
# Comp:  2              HeII4687      4.480       1.6     767   574
# Comp:  2               HeI5876      2.301       1.6     767   574
# Comp:  2          [OIII]5007_d      0.000       2.0     767   574
# Comp:  2            [OI]6300_d      0.000       2.0     767   574
# Comp:  2           [NII]6583_d      0.000       1.9     767   574
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63       120
#  comp.  1:        53         1
#  comp.  2:       667       190
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.52      53     1
# Comp:  1                Halpha      1.404      0.54      53     1
# Comp:  2             [SII]6716     0.3881      0.92     667   190
# Comp:  2             [SII]6731      0.000      0.92     667   190
# Comp:  2              HeII4687      1.884      0.92     667   190
# Comp:  2               HeI5876      2.927      0.92     667   190
# Comp:  2          [OIII]5007_d     0.7767       1.2     667   190
# Comp:  2            [OI]6300_d     0.3418       1.2     667   190
# Comp:  2           [NII]6583_d      0.000       1.2     667   190
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        44
#  comp.  1:        40        28
#  comp.  2:       581       316
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3090      0.55      40    28
# Comp:  1                Halpha      1.453      0.56      40    28
# Comp:  2             [SII]6716    0.01959       1.2     581   316
# Comp:  2             [SII]6731      0.000       1.2     581   316
# Comp:  2              HeII4687     0.7873       1.2     581   316
# Comp:  2               HeI5876      3.684       1.2     581   316
# Comp:  2          [OIII]5007_d     0.2492       1.5     581   316
# Comp:  2            [OI]6300_d      2.119       1.5     581   316
# Comp:  2           [NII]6583_d      1.533       1.5     581   316
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:        51        51
#  comp.  2:       473       100
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1464      0.59      51    51
# Comp:  1                Halpha      1.779      0.59      51    51
# Comp:  2             [SII]6716     0.5856      0.71     473   100
# Comp:  2             [SII]6731     0.1442      0.71     473   100
# Comp:  2              HeII4687     0.2472      0.71     473   100
# Comp:  2               HeI5876      1.543      0.71     473   100
# Comp:  2          [OIII]5007_d      1.714      0.89     473   100
# Comp:  2            [OI]6300_d     0.8689      0.89     473   100
# Comp:  2           [NII]6583_d    0.04027      0.89     473   100
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        69
#  comp.  1:        49         1
#  comp.  2:       625       164
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9075      0.52      49     1
# Comp:  1                Halpha      1.488      0.54      49     1
# Comp:  2             [SII]6716      0.000      0.86     625   164
# Comp:  2             [SII]6731      0.000      0.86     625   164
# Comp:  2              HeII4687     0.4105      0.86     625   164
# Comp:  2               HeI5876      3.937      0.86     625   164
# Comp:  2          [OIII]5007_d      0.000       1.1     625   164
# Comp:  2            [OI]6300_d      1.300       1.1     625   164
# Comp:  2           [NII]6583_d     0.2817       1.1     625   164
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        67
#  comp.  1:        49        30
#  comp.  2:       671       307
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.232      0.55      49    30
# Comp:  1                Halpha      1.443      0.56      49    30
# Comp:  2             [SII]6716     0.5925       1.2     671   307
# Comp:  2             [SII]6731     0.8139       1.2     671   307
# Comp:  2              HeII4687      0.000       1.1     671   307
# Comp:  2               HeI5876      2.108       1.1     671   307
# Comp:  2          [OIII]5007_d      1.626       1.4     671   307
# Comp:  2            [OI]6300_d     0.9230       1.4     671   307
# Comp:  2           [NII]6583_d     0.3931       1.5     671   307
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        48
#  comp.  1:        24        39
#  comp.  2:       729       598
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6246      0.57      24    39
# Comp:  1                Halpha      1.971      0.57      24    39
# Comp:  2             [SII]6716      0.000       2.4     729   598
# Comp:  2             [SII]6731     0.7833       2.4     729   598
# Comp:  2              HeII4687      2.567       1.6     729   598
# Comp:  2               HeI5876      2.889       1.6     729   598
# Comp:  2          [OIII]5007_d      0.000       2.0     729   598
# Comp:  2            [OI]6300_d      3.700       2.0     729   598
# Comp:  2           [NII]6583_d      1.818       1.9     729   598
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:        25        60
#  comp.  2:       624       420
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5584      0.61      25    60
# Comp:  1                Halpha      2.413      0.62      25    60
# Comp:  2             [SII]6716      0.000       1.6     624   420
# Comp:  2             [SII]6731      1.172       1.6     624   420
# Comp:  2              HeII4687      1.751       1.3     624   420
# Comp:  2               HeI5876      2.332       1.3     624   420
# Comp:  2          [OIII]5007_d     0.8244       1.7     624   420
# Comp:  2            [OI]6300_d      4.004       1.7     624   420
# Comp:  2           [NII]6583_d     0.3673       1.7     624   420
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:        45        54
#  comp.  2:       582       197
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.60      45    54
# Comp:  1                Halpha      1.517      0.61      45    54
# Comp:  2             [SII]6716     0.4432      0.93     582   197
# Comp:  2             [SII]6731     0.2784      0.93     582   197
# Comp:  2              HeII4687      1.450      0.93     582   197
# Comp:  2               HeI5876      2.967      0.93     582   197
# Comp:  2          [OIII]5007_d      2.119       1.2     582   197
# Comp:  2            [OI]6300_d      1.768       1.2     582   197
# Comp:  2           [NII]6583_d      1.107       1.2     582   197
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:        51         7
#  comp.  2:       580       345
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6341      0.53      51     7
# Comp:  1                Halpha      1.535      0.53      51     7
# Comp:  2             [SII]6716      1.278       1.3     580   345
# Comp:  2             [SII]6731      0.000       1.3     580   345
# Comp:  2              HeII4687     0.9802       1.2     580   345
# Comp:  2               HeI5876      3.589       1.2     580   345
# Comp:  2          [OIII]5007_d      0.000       1.5     580   345
# Comp:  2            [OI]6300_d      1.886       1.5     580   345
# Comp:  2           [NII]6583_d      0.000       1.5     580   345
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:        38         1
#  comp.  2:       615       213
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.52      38     1
# Comp:  1                Halpha      1.244      0.54      38     1
# Comp:  2             [SII]6716      1.024      0.97     615   213
# Comp:  2             [SII]6731    0.05833      0.97     615   213
# Comp:  2              HeII4687     0.7060      0.96     615   213
# Comp:  2               HeI5876      3.365      0.96     615   213
# Comp:  2          [OIII]5007_d      1.486       1.2     615   213
# Comp:  2            [OI]6300_d     0.1537       1.2     615   213
# Comp:  2           [NII]6583_d      0.000       1.2     615   213
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        31
#  comp.  1:        41        24
#  comp.  2:       583       322
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      41    24
# Comp:  1                Halpha      1.288      0.55      41    24
# Comp:  2             [SII]6716      0.000       1.3     583   322
# Comp:  2             [SII]6731   0.001151       1.3     583   322
# Comp:  2              HeII4687     0.9586       1.2     583   322
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4225      0.59      43    53
# Comp:  1                Halpha      1.755      0.61      43    53
# Comp:  2             [SII]6716     0.6913       1.0     583   229
# Comp:  2             [SII]6731     0.1149       1.0     583   229
# Comp:  2              HeII4687     0.4017       1.0     583   229
# Comp:  2               HeI5876      3.144       1.0     583   229
# Comp:  2          [OIII]5007_d      1.550       1.3     583   229
# Comp:  2            [OI]6300_d      1.960       1.3     583   229
# Comp:  2           [NII]6583_d      0.000       1.3     583   229
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        23
#  comp.  1:        33        95
#  comp.  2:       491       175
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.455      0.69      33    95
# Comp:  1                Halpha      2.340      0.71      33    95
# Comp:  2             [SII]6716      0.000      0.88     491   175
# Comp:  2             [SII]6731     0.3751      0.88     491   175
# Comp:  2              HeII4687    0.04392      0.88     491   175
# Comp:  2               HeI5876      2.354      0.88     491   175
# Comp:  2          [OIII]5007_d    0.07771       1.1     491   175
# Comp:  2            [OI]6300_d      2.553       1.1     491   175
# Comp:  2           [NII]6583_d      0.000       1.1     491   175
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -19        98
#  comp.  2:       347       160
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.481      0.70     -19    98
# Comp:  1                Halpha      1.825      0.70     -19    98
# Comp:  2             [SII]6716     0.7504      0.85     347   160
# Comp:  2             [SII]6731     0.1366      0.85     347   160
# Comp:  2              HeII4687     0.2827      0.85     347   160
# Comp:  2               HeI5876      2.226      0.85     347   160
# Comp:  2          [OIII]5007_d      4.023       1.1     347   160
# Comp:  2            [OI]6300_d      0.000       1.1     347   160
# Comp:  2           [NII]6583_d      0.000       1.1     347   160
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        28
#  comp.  1:        31        41
#  comp.  2:       346       411
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1264      0.57      31    41
# Comp:  1                Halpha      1.569      0.57      31    41
# Comp:  2             [SII]6716     0.5802       1.6     346   411
# Comp:  2             [SII]6731      1.159       1.6     346   411
# Comp:  2              HeII4687      1.552       1.3     346   411
# Comp:  2               HeI5876      5.006       1.3     346   411
# Comp:  2          [OIII]5007_d      0.000       1.7     346   411
# Comp:  2            [OI]6300_d     0.1027       1.7     346   411
# Comp:  2           [NII]6583_d      0.000       1.7     346   411
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        49
#  comp.  1:        41        21
#  comp.  2:       566       314
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.54      41    21
# Comp:  1                Halpha      1.096      0.55      41    21
# Comp:  2             [SII]6716      0.000       1.2     566   314
# Comp:  2             [SII]6731     0.5831       1.2     566   314
# Comp:  2              HeII4687      1.109       1.2     566   314
# Comp:  2               HeI5876      2.819       1.2     566   314
# Comp:  2          [OIII]5007_d      1.754       1.5     566   314
# Comp:  2            [OI]6300_d     0.5198       1.5     566   314
# Comp:  2           [NII]6583_d      1.110       1.5     566   314
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        49
#  comp.  1:        44        19
#  comp.  2:       573       316
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4105      0.54      44    19
# Comp:  1                Halpha      1.280      0.54      44    19
# Comp:  2             [SII]6716      0.000       1.2     573   316
# Comp:  2             [SII]6731      1.295       1.2     573   316
# Comp:  2              HeII4687     0.9619       1.2     573   316
# Comp:  2               HeI5876      4.184       1.2     573   316
# Comp:  2          [OIII]5007_d      2.693       1.5     573   316
# Comp:  2            [OI]6300_d      2.338       1.5     573   316
# Comp:  2           [NII]6583_d      2.353       1.5     573   316
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        40
#  comp.  1:        14        67
#  comp.  2:       700       328
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.386      0.63      14    67
# Comp:  1                Halpha      2.271      0.64      14    67
# Comp:  2             [SII]6716      0.000       1.3     700   328
# Comp:  2             [SII]6731      0.000       1.3     700   328
# Comp:  2              HeII4687     0.7783       1.2     700   328
# Comp:  2               HeI5876      3.593       1.2     700   328
# Comp:  2          [OIII]5007_d     0.3813       1.5     700   328
# Comp:  2            [OI]6300_d     0.3860       1.5     700   328
# Comp:  2           [NII]6583_d      0.000       1.5     700   328
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        48         1
#  comp.  2:       609       115
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.52      48     1
# Comp:  1                Halpha     0.9474      0.54      48     1
# Comp:  2             [SII]6716      0.000      0.74     609   115
# Comp:  2             [SII]6731    0.02086      0.74     609   115
# Comp:  2              HeII4687      0.000      0.74     609   115
# Comp:  2               HeI5876      2.468      0.74     609   115
# Comp:  2          [OIII]5007_d      0.000      0.94     609   115
# Comp:  2            [OI]6300_d      0.000      0.94     609   115
# Comp:  2           [NII]6583_d      1.758      0.96     609   115
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:         3        67
#  comp.  2:       507       406
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.763      0.63       3    67
# Comp:  1                Halpha      2.459      0.64       3    67
# Comp:  2             [SII]6716      0.000       1.6     507   406
# Comp:  2             [SII]6731      0.000       1.6     507   406
# Comp:  2              HeII4687      2.502       1.3     507   406
# Comp:  2               HeI5876      2.977       1.3     507   406
# Comp:  2          [OIII]5007_d      0.000       1.7     507   406
# Comp:  2            [OI]6300_d      0.000       1.7     507   406
# Comp:  2           [NII]6583_d      0.000       1.7     507   406
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:        45        32
#  comp.  2:       759       651
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2544      0.55      45    32
# Comp:  1                Halpha      1.449      0.56      45    32
# Comp:  2             [SII]6716      0.000       2.7     759   651
# Comp:  2             [SII]6731      0.000       2.7     759   651
# Comp:  2              HeII4687      3.099       1.7     759   651
# Comp:  2               HeI5876      2.614       1.7     759   651
# Comp:  2          [OIII]5007_d      0.000       2.1     759   651
# Comp:  2            [OI]6300_d      0.000       2.1     759   651
# Comp:  2           [NII]6583_d      0.000       2.0     759   651
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58       102
#  comp.  1:        43        27
#  comp.  2:       573       318
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6395      0.54      43    27
# Comp:  1                Halpha      1.617      0.55      43    27
# Comp:  2             [SII]6716     0.5569       1.3     573   318
# Comp:  2             [SII]6731      0.000       1.3     573   318
# Comp:  2              HeII4687      2.431       1.2     573   318
# Comp:  2               HeI5876      3.606       1.2     573   318
# Comp:  2          [OIII]5007_d      1.134       1.5     573   318
# Comp:  2            [OI]6300_d     0.7245       1.5     573   318
# Comp:  2           [NII]6583_d      0.000       1.5     573   318
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:         6       110
#  comp.  2:       506         1
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.396      0.73       6   110
# Comp:  1                Halpha      2.919      0.74       6   110
# Comp:  2             [SII]6716     0.5509      0.52     506     1
# Comp:  2             [SII]6731     0.1381      0.52     506     1
# Comp:  2              HeII4687     0.3023      0.52     506     1
# Comp:  2               HeI5876     0.3937      0.52     506     1
# Comp:  2          [OIII]5007_d      2.230      0.66     506     1
# Comp:  2            [OI]6300_d     0.3997      0.66     506     1
# Comp:  2           [NII]6583_d      0.000      0.67     506     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:        39        66
#  comp.  2:       509       510
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.110      0.62      39    66
# Comp:  1                Halpha      1.966      0.64      39    66
# Comp:  2             [SII]6716      0.000       2.0     509   510
# Comp:  2             [SII]6731     0.5631       2.0     509   510
# Comp:  2              HeII4687      3.002       1.5     509   510
# Comp:  2               HeI5876      5.820       1.5     509   510
# Comp:  2          [OIII]5007_d      3.398       1.8     509   510
# Comp:  2            [OI]6300_d      0.000       1.8     509   510
# Comp:  2           [NII]6583_d      0.000       1.8     509   510
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:         9        84
#  comp.  2:       376       332
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.104      0.67       9    84
# Comp:  1                Halpha      2.030      0.68       9    84
# Comp:  2             [SII]6716      0.000       1.3     376   332
# Comp:  2             [SII]6731      0.000       1.3     376   332
# Comp:  2              HeII4687     0.6525       1.2     376   332
# Comp:  2               HeI5876      3.094       1.2     376   332
# Comp:  2          [OIII]5007_d      1.286       1.5     376   332
# Comp:  2            [OI]6300_d     0.9017       1.5     376   332
# Comp:  2           [NII]6583_d      0.000       1.5     376   332
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_6_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_6", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_6_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_6_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_6_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
