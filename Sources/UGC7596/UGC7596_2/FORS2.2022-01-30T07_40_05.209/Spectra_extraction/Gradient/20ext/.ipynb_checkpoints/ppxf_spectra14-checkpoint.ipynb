# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_14.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_14']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02008058 0.0287769  0.01418407 ... 0.011557   0.00676829 0.01081461] [0.00500945 0.00500945 0.00500945 ... 0.00500945 0.00500945 0.00500945]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
# chi2/DOF: 0.1946; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
# chi2/DOF: 0.07016; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-34.56108329,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -67        22
#  comp.  2:       -54        52
# chi2/DOF: 2.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.386      0.59     -67    22
# Comp:  1                Halpha      8.131      0.59     -67    22
# Comp:  2             [SII]6716      2.346      0.65     -54    52
# Comp:  2             [SII]6731      2.445      0.65     -54    52
# Comp:  2              HeII4687      1.144      0.65     -54    52
# Comp:  2               HeI5876     0.1032      0.65     -54    52
# Comp:  2          [OIII]5007_d      2.566      0.82     -54    52
# Comp:  2            [OI]6300_d      0.000      0.82     -54    52
# Comp:  2           [NII]6583_d      2.104      0.82     -54    52
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  5.619; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  10.73; gas flux:     11 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.526; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.547; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.258; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.1137; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.124; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.665; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -63        19
#  comp.  2:       -47        70
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.639      0.59     -63    19
# Comp:  1                Halpha      8.319      0.59     -63    19
# Comp:  2             [SII]6716      2.442      0.69     -47    70
# Comp:  2             [SII]6731      2.962      0.69     -47    70
# Comp:  2              HeII4687     0.8940      0.69     -47    70
# Comp:  2               HeI5876      0.000      0.69     -47    70
# Comp:  2          [OIII]5007_d      2.673      0.88     -47    70
# Comp:  2            [OI]6300_d      1.903      0.88     -47    70
# Comp:  2           [NII]6583_d      1.953      0.88     -47    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -69        31
#  comp.  2:       -59        56
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.678      0.60     -69    31
# Comp:  1                Halpha      8.753      0.60     -69    31
# Comp:  2             [SII]6716      2.837      0.66     -59    56
# Comp:  2             [SII]6731      2.615      0.66     -59    56
# Comp:  2              HeII4687      1.249      0.66     -59    56
# Comp:  2               HeI5876     0.1303      0.66     -59    56
# Comp:  2          [OIII]5007_d      2.009      0.83     -59    56
# Comp:  2            [OI]6300_d      0.000      0.83     -59    56
# Comp:  2           [NII]6583_d      2.191      0.83     -59    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        78
#  comp.  1:       -69        43
#  comp.  2:       -61        80
# chi2/DOF: 2.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.837      0.63     -69    43
# Comp:  1                Halpha      9.229      0.63     -69    43
# Comp:  2             [SII]6716      2.637      0.72     -61    80
# Comp:  2             [SII]6731      2.553      0.72     -61    80
# Comp:  2              HeII4687      1.064      0.72     -61    80
# Comp:  2               HeI5876     0.1218      0.72     -61    80
# Comp:  2          [OIII]5007_d      3.611      0.91     -61    80
# Comp:  2            [OI]6300_d     0.6480      0.91     -61    80
# Comp:  2           [NII]6583_d      2.547      0.91     -61    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -70        35
#  comp.  2:       -61        50
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.282      0.61     -70    35
# Comp:  1                Halpha      8.939      0.61     -70    35
# Comp:  2             [SII]6716      2.320      0.64     -61    50
# Comp:  2             [SII]6731      2.471      0.64     -61    50
# Comp:  2              HeII4687      1.280      0.64     -61    50
# Comp:  2               HeI5876      0.000      0.64     -61    50
# Comp:  2          [OIII]5007_d      2.619      0.81     -61    50
# Comp:  2            [OI]6300_d      0.000      0.81     -61    50
# Comp:  2           [NII]6583_d      2.149      0.81     -61    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -70        29
#  comp.  2:       -55        61
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.331      0.60     -70    29
# Comp:  1                Halpha      8.875      0.60     -70    29
# Comp:  2             [SII]6716      2.730      0.67     -55    61
# Comp:  2             [SII]6731      2.469      0.67     -55    61
# Comp:  2              HeII4687      1.101      0.67     -55    61
# Comp:  2               HeI5876     0.4837      0.67     -55    61
# Comp:  2          [OIII]5007_d      3.263      0.85     -55    61
# Comp:  2            [OI]6300_d      2.501      0.85     -55    61
# Comp:  2           [NII]6583_d      2.467      0.85     -55    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -73        33
#  comp.  2:       -63        28
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.965      0.61     -73    33
# Comp:  1                Halpha      9.205      0.61     -73    33
# Comp:  2             [SII]6716      2.185      0.60     -63    28
# Comp:  2             [SII]6731      2.122      0.60     -63    28
# Comp:  2              HeII4687      1.002      0.60     -63    28
# Comp:  2               HeI5876      0.000      0.60     -63    28
# Comp:  2          [OIII]5007_d      1.809      0.76     -63    28
# Comp:  2            [OI]6300_d      1.307      0.76     -63    28
# Comp:  2           [NII]6583_d      1.929      0.76     -63    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -71        33
#  comp.  2:       -58        57
# chi2/DOF: 2.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.592      0.61     -71    33
# Comp:  1                Halpha      9.304      0.61     -71    33
# Comp:  2             [SII]6716      2.910      0.66     -58    57
# Comp:  2             [SII]6731      2.702      0.66     -58    57
# Comp:  2              HeII4687      1.224      0.66     -58    57
# Comp:  2               HeI5876    0.07219      0.66     -58    57
# Comp:  2          [OIII]5007_d      2.772      0.83     -58    57
# Comp:  2            [OI]6300_d    0.03653      0.83     -58    57
# Comp:  2           [NII]6583_d      2.282      0.83     -58    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -64         1
#  comp.  2:       -54        47
# chi2/DOF: 2.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.249      0.57     -64     1
# Comp:  1                Halpha      8.011      0.57     -64     1
# Comp:  2             [SII]6716      1.810      0.64     -54    47
# Comp:  2             [SII]6731      2.043      0.64     -54    47
# Comp:  2              HeII4687     0.5961      0.64     -54    47
# Comp:  2               HeI5876     0.3208      0.64     -54    47
# Comp:  2          [OIII]5007_d      2.288      0.80     -54    47
# Comp:  2            [OI]6300_d      1.757      0.80     -54    47
# Comp:  2           [NII]6583_d      2.346      0.80     -54    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -68        40
#  comp.  2:       -52        56
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.189      0.62     -68    40
# Comp:  1                Halpha      8.916      0.62     -68    40
# Comp:  2             [SII]6716      2.244      0.66     -52    56
# Comp:  2             [SII]6731      2.437      0.66     -52    56
# Comp:  2              HeII4687      1.452      0.66     -52    56
# Comp:  2               HeI5876     0.4406      0.66     -52    56
# Comp:  2          [OIII]5007_d      2.850      0.83     -52    56
# Comp:  2            [OI]6300_d      0.000      0.83     -52    56
# Comp:  2           [NII]6583_d      2.507      0.83     -52    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -71        23
#  comp.  2:       -65        71
# chi2/DOF: 2.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.710      0.59     -71    23
# Comp:  1                Halpha      9.063      0.59     -71    23
# Comp:  2             [SII]6716      2.575      0.70     -65    71
# Comp:  2             [SII]6731      3.230      0.70     -65    71
# Comp:  2              HeII4687     0.5035      0.70     -65    71
# Comp:  2               HeI5876     0.1175      0.70     -65    71
# Comp:  2          [OIII]5007_d      3.688      0.88     -65    71
# Comp:  2            [OI]6300_d      0.000      0.88     -65    71
# Comp:  2           [NII]6583_d      2.494      0.88     -65    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       110
#  comp.  1:       -67        24
#  comp.  2:       -54        56
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.807      0.59     -67    24
# Comp:  1                Halpha      7.847      0.59     -67    24
# Comp:  2             [SII]6716      2.460      0.66     -54    56
# Comp:  2             [SII]6731      3.109      0.66     -54    56
# Comp:  2              HeII4687      1.666      0.66     -54    56
# Comp:  2               HeI5876     0.2065      0.66     -54    56
# Comp:  2          [OIII]5007_d      2.266      0.83     -54    56
# Comp:  2            [OI]6300_d     0.3836      0.83     -54    56
# Comp:  2           [NII]6583_d      2.080      0.83     -54    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -62        34
#  comp.  2:       -41        68
# chi2/DOF: 2.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.970      0.61     -62    34
# Comp:  1                Halpha      8.025      0.61     -62    34
# Comp:  2             [SII]6716      2.986      0.69     -41    68
# Comp:  2             [SII]6731      2.703      0.69     -41    68
# Comp:  2              HeII4687     0.7099      0.69     -41    68
# Comp:  2               HeI5876      0.000      0.69     -41    68
# Comp:  2          [OIII]5007_d      3.450      0.87     -41    68
# Comp:  2            [OI]6300_d      1.526      0.87     -41    68
# Comp:  2           [NII]6583_d      2.164      0.87     -41    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        29
#  comp.  1:       -68        23
#  comp.  2:       -54        52
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.964      0.59     -68    23
# Comp:  1                Halpha      8.630      0.59     -68    23
# Comp:  2             [SII]6716      2.763      0.65     -54    52
# Comp:  2             [SII]6731      2.868      0.65     -54    52
# Comp:  2              HeII4687      1.336      0.65     -54    52
# Comp:  2               HeI5876      0.000      0.65     -54    52
# Comp:  2          [OIII]5007_d      2.793      0.82     -54    52
# Comp:  2            [OI]6300_d      1.317      0.82     -54    52
# Comp:  2           [NII]6583_d      2.264      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -71        29
#  comp.  2:       -50        41
# chi2/DOF: 2.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.853      0.60     -71    29
# Comp:  1                Halpha      9.064      0.60     -71    29
# Comp:  2             [SII]6716      2.370      0.62     -50    41
# Comp:  2             [SII]6731      2.449      0.62     -50    41
# Comp:  2              HeII4687      1.205      0.62     -50    41
# Comp:  2               HeI5876      0.000      0.62     -50    41
# Comp:  2          [OIII]5007_d      1.616      0.79     -50    41
# Comp:  2            [OI]6300_d      0.000      0.79     -50    41
# Comp:  2           [NII]6583_d      1.853      0.79     -50    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -66         2
#  comp.  2:       -49        33
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.383      0.57     -66     2
# Comp:  1                Halpha      8.088      0.57     -66     2
# Comp:  2             [SII]6716      2.337      0.61     -49    33
# Comp:  2             [SII]6731      2.835      0.61     -49    33
# Comp:  2              HeII4687      1.472      0.61     -49    33
# Comp:  2               HeI5876      0.000      0.61     -49    33
# Comp:  2          [OIII]5007_d      2.384      0.77     -49    33
# Comp:  2            [OI]6300_d      0.000      0.77     -49    33
# Comp:  2           [NII]6583_d      1.659      0.77     -49    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        74
#  comp.  1:       -72        30
#  comp.  2:       -50        42
# chi2/DOF: 2.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.788      0.60     -72    30
# Comp:  1                Halpha      8.397      0.60     -72    30
# Comp:  2             [SII]6716      2.164      0.63     -50    42
# Comp:  2             [SII]6731      2.065      0.63     -50    42
# Comp:  2              HeII4687     0.9870      0.63     -50    42
# Comp:  2               HeI5876      0.000      0.63     -50    42
# Comp:  2          [OIII]5007_d      2.357      0.79     -50    42
# Comp:  2            [OI]6300_d    0.08402      0.79     -50    42
# Comp:  2           [NII]6583_d      2.236      0.79     -50    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -72        22
#  comp.  2:       -49        64
# chi2/DOF: 2.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.153      0.59     -72    22
# Comp:  1                Halpha      8.357      0.59     -72    22
# Comp:  2             [SII]6716      2.069      0.68     -49    64
# Comp:  2             [SII]6731      2.110      0.68     -49    64
# Comp:  2              HeII4687     0.6615      0.68     -49    64
# Comp:  2               HeI5876      0.000      0.68     -49    64
# Comp:  2          [OIII]5007_d      2.922      0.86     -49    64
# Comp:  2            [OI]6300_d      0.000      0.86     -49    64
# Comp:  2           [NII]6583_d      1.906      0.86     -49    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -68         1
#  comp.  2:       -55        47
# chi2/DOF: 2.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.455      0.57     -68     1
# Comp:  1                Halpha      7.890      0.57     -68     1
# Comp:  2             [SII]6716      2.827      0.64     -55    47
# Comp:  2             [SII]6731      2.029      0.64     -55    47
# Comp:  2              HeII4687      1.044      0.64     -55    47
# Comp:  2               HeI5876      0.000      0.64     -55    47
# Comp:  2          [OIII]5007_d      2.517      0.80     -55    47
# Comp:  2            [OI]6300_d      0.000      0.80     -55    47
# Comp:  2           [NII]6583_d      2.440      0.80     -55    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        23
#  comp.  1:       -67        22
#  comp.  2:       -53        53
# chi2/DOF: 2.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.485      0.59     -67    22
# Comp:  1                Halpha      8.964      0.59     -67    22
# Comp:  2             [SII]6716      2.320      0.65     -53    53
# Comp:  2             [SII]6731      3.074      0.65     -53    53
# Comp:  2              HeII4687     0.8747      0.65     -53    53
# Comp:  2               HeI5876      0.000      0.65     -53    53
# Comp:  2          [OIII]5007_d      2.452      0.82     -53    53
# Comp:  2            [OI]6300_d      0.000      0.82     -53    53
# Comp:  2           [NII]6583_d      2.133      0.82     -53    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        48
#  comp.  1:       -67        21
#  comp.  2:       -54        52
# chi2/DOF: 2.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.277      0.59     -67    21
# Comp:  1                Halpha      7.805      0.59     -67    21
# Comp:  2             [SII]6716      2.094      0.65     -54    52
# Comp:  2             [SII]6731      2.252      0.65     -54    52
# Comp:  2              HeII4687     0.8808      0.65     -54    52
# Comp:  2               HeI5876     0.1900      0.65     -54    52
# Comp:  2          [OIII]5007_d      3.182      0.82     -54    52
# Comp:  2            [OI]6300_d     0.1295      0.82     -54    52
# Comp:  2           [NII]6583_d      2.202      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        34
#  comp.  1:       -75        41
#  comp.  2:       -44        67
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.123      0.62     -75    41
# Comp:  1                Halpha      8.864      0.62     -75    41
# Comp:  2             [SII]6716      2.883      0.68     -44    67
# Comp:  2             [SII]6731      3.187      0.68     -44    67
# Comp:  2              HeII4687     0.6782      0.68     -44    67
# Comp:  2               HeI5876      0.000      0.68     -44    67
# Comp:  2          [OIII]5007_d      2.483      0.86     -44    67
# Comp:  2            [OI]6300_d      0.000      0.86     -44    67
# Comp:  2           [NII]6583_d      2.212      0.86     -44    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -73        22
#  comp.  2:       -49        56
# chi2/DOF: 2.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.858      0.59     -73    22
# Comp:  1                Halpha      8.260      0.59     -73    22
# Comp:  2             [SII]6716      2.120      0.66     -49    56
# Comp:  2             [SII]6731      2.558      0.66     -49    56
# Comp:  2              HeII4687     0.7663      0.66     -49    56
# Comp:  2               HeI5876     0.1141      0.66     -49    56
# Comp:  2          [OIII]5007_d      2.559      0.83     -49    56
# Comp:  2            [OI]6300_d     0.3899      0.83     -49    56
# Comp:  2           [NII]6583_d      2.313      0.83     -49    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -68        28
#  comp.  2:       -65        50
# chi2/DOF: 2.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.142      0.60     -68    28
# Comp:  1                Halpha      8.768      0.60     -68    28
# Comp:  2             [SII]6716      2.664      0.64     -65    50
# Comp:  2             [SII]6731      2.970      0.64     -65    50
# Comp:  2              HeII4687     0.9390      0.64     -65    50
# Comp:  2               HeI5876     0.5510      0.64     -65    50
# Comp:  2          [OIII]5007_d      2.499      0.81     -65    50
# Comp:  2            [OI]6300_d      0.000      0.81     -65    50
# Comp:  2           [NII]6583_d      1.954      0.81     -65    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -69        46
#  comp.  2:       -33        41
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.052      0.63     -69    46
# Comp:  1                Halpha      8.548      0.63     -69    46
# Comp:  2             [SII]6716      2.226      0.62     -33    41
# Comp:  2             [SII]6731      2.175      0.62     -33    41
# Comp:  2              HeII4687      1.298      0.62     -33    41
# Comp:  2               HeI5876     0.1568      0.62     -33    41
# Comp:  2          [OIII]5007_d      2.459      0.79     -33    41
# Comp:  2            [OI]6300_d      0.000      0.79     -33    41
# Comp:  2           [NII]6583_d      1.896      0.79     -33    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        16
#  comp.  1:       -67        23
#  comp.  2:       -54        52
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.904      0.59     -67    23
# Comp:  1                Halpha      8.120      0.59     -67    23
# Comp:  2             [SII]6716      2.282      0.65     -54    52
# Comp:  2             [SII]6731      2.474      0.65     -54    52
# Comp:  2              HeII4687      1.779      0.65     -54    52
# Comp:  2               HeI5876     0.4945      0.65     -54    52
# Comp:  2          [OIII]5007_d      2.528      0.82     -54    52
# Comp:  2            [OI]6300_d     0.1540      0.82     -54    52
# Comp:  2           [NII]6583_d      1.924      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -61        16
#  comp.  2:       -39        67
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.002      0.58     -61    16
# Comp:  1                Halpha      8.325      0.58     -61    16
# Comp:  2             [SII]6716      2.239      0.69     -39    67
# Comp:  2             [SII]6731      2.821      0.69     -39    67
# Comp:  2              HeII4687      1.504      0.69     -39    67
# Comp:  2               HeI5876     0.1564      0.69     -39    67
# Comp:  2          [OIII]5007_d      2.855      0.87     -39    67
# Comp:  2            [OI]6300_d    0.08987      0.87     -39    67
# Comp:  2           [NII]6583_d      2.313      0.87     -39    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45       105
#  comp.  1:       -68        22
#  comp.  2:       -53        56
# chi2/DOF: 2.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.698      0.59     -68    22
# Comp:  1                Halpha      7.742      0.59     -68    22
# Comp:  2             [SII]6716      2.755      0.66     -53    56
# Comp:  2             [SII]6731      2.977      0.66     -53    56
# Comp:  2              HeII4687     0.7424      0.66     -53    56
# Comp:  2               HeI5876    0.05890      0.66     -53    56
# Comp:  2          [OIII]5007_d      2.585      0.83     -53    56
# Comp:  2            [OI]6300_d      0.000      0.83     -53    56
# Comp:  2           [NII]6583_d      1.958      0.83     -53    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -70        16
#  comp.  2:       -54        76
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.528      0.58     -70    16
# Comp:  1                Halpha      8.195      0.58     -70    16
# Comp:  2             [SII]6716      2.600      0.71     -54    76
# Comp:  2             [SII]6731      2.597      0.71     -54    76
# Comp:  2              HeII4687     0.9941      0.71     -54    76
# Comp:  2               HeI5876     0.1671      0.71     -54    76
# Comp:  2          [OIII]5007_d      3.593      0.90     -54    76
# Comp:  2            [OI]6300_d      1.686      0.90     -54    76
# Comp:  2           [NII]6583_d      2.393      0.90     -54    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -66         5
#  comp.  2:       -55        66
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.620      0.57     -66     5
# Comp:  1                Halpha      8.386      0.57     -66     5
# Comp:  2             [SII]6716      2.236      0.68     -55    66
# Comp:  2             [SII]6731      1.881      0.68     -55    66
# Comp:  2              HeII4687      1.699      0.68     -55    66
# Comp:  2               HeI5876     0.1143      0.68     -55    66
# Comp:  2          [OIII]5007_d      2.288      0.86     -55    66
# Comp:  2            [OI]6300_d     0.1957      0.86     -55    66
# Comp:  2           [NII]6583_d      2.105      0.86     -55    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        32
#  comp.  1:       -67        23
#  comp.  2:       -55        52
# chi2/DOF: 2.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.545      0.59     -67    23
# Comp:  1                Halpha      8.725      0.59     -67    23
# Comp:  2             [SII]6716      2.456      0.65     -55    52
# Comp:  2             [SII]6731      2.433      0.65     -55    52
# Comp:  2              HeII4687      1.088      0.65     -55    52
# Comp:  2               HeI5876     0.1561      0.65     -55    52
# Comp:  2          [OIII]5007_d      3.099      0.82     -55    52
# Comp:  2            [OI]6300_d     0.2248      0.82     -55    52
# Comp:  2           [NII]6583_d      1.899      0.82     -55    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        30
#  comp.  1:       -67        21
#  comp.  2:       -53        52
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.856      0.59     -67    21
# Comp:  1                Halpha      7.941      0.59     -67    21
# Comp:  2             [SII]6716      2.259      0.65     -53    52
# Comp:  2             [SII]6731      2.181      0.65     -53    52
# Comp:  2              HeII4687      1.689      0.65     -53    52
# Comp:  2               HeI5876    0.09718      0.65     -53    52
# Comp:  2          [OIII]5007_d      2.383      0.82     -53    52
# Comp:  2            [OI]6300_d     0.5920      0.82     -53    52
# Comp:  2           [NII]6583_d      2.203      0.82     -53    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116       127
#  comp.  1:       -62         1
#  comp.  2:       -74        72
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.691      0.57     -62     1
# Comp:  1                Halpha      7.411      0.57     -62     1
# Comp:  2             [SII]6716      2.252      0.70     -74    72
# Comp:  2             [SII]6731      2.335      0.70     -74    72
# Comp:  2              HeII4687      1.189      0.70     -74    72
# Comp:  2               HeI5876     0.1239      0.70     -74    72
# Comp:  2          [OIII]5007_d      3.254      0.88     -74    72
# Comp:  2            [OI]6300_d      0.000      0.88     -74    72
# Comp:  2           [NII]6583_d      2.198      0.88     -74    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -69        22
#  comp.  2:       -44        54
# chi2/DOF: 2.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.549      0.59     -69    22
# Comp:  1                Halpha      8.200      0.59     -69    22
# Comp:  2             [SII]6716      2.763      0.65     -44    54
# Comp:  2             [SII]6731      2.177      0.65     -44    54
# Comp:  2              HeII4687     0.6434      0.65     -44    54
# Comp:  2               HeI5876     0.3673      0.65     -44    54
# Comp:  2          [OIII]5007_d      2.107      0.82     -44    54
# Comp:  2            [OI]6300_d      0.000      0.82     -44    54
# Comp:  2           [NII]6583_d      2.096      0.82     -44    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        16
#  comp.  1:       -67        22
#  comp.  2:       -54        53
# chi2/DOF: 2.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.252      0.59     -67    22
# Comp:  1                Halpha      8.350      0.59     -67    22
# Comp:  2             [SII]6716      2.847      0.65     -54    53
# Comp:  2             [SII]6731      2.461      0.65     -54    53
# Comp:  2              HeII4687     0.9917      0.65     -54    53
# Comp:  2               HeI5876    0.08443      0.65     -54    53
# Comp:  2          [OIII]5007_d      2.418      0.82     -54    53
# Comp:  2            [OI]6300_d      0.000      0.82     -54    53
# Comp:  2           [NII]6583_d      2.398      0.82     -54    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        88
#  comp.  1:       -67        22
#  comp.  2:       -55        52
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.036      0.59     -67    22
# Comp:  1                Halpha      8.205      0.59     -67    22
# Comp:  2             [SII]6716      2.569      0.65     -55    52
# Comp:  2             [SII]6731      2.672      0.65     -55    52
# Comp:  2              HeII4687     0.9582      0.65     -55    52
# Comp:  2               HeI5876    0.01530      0.65     -55    52
# Comp:  2          [OIII]5007_d      1.853      0.82     -55    52
# Comp:  2            [OI]6300_d      0.000      0.82     -55    52
# Comp:  2           [NII]6583_d      1.935      0.82     -55    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -73        49
#  comp.  2:       -57        33
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.390      0.64     -73    49
# Comp:  1                Halpha      9.404      0.64     -73    49
# Comp:  2             [SII]6716      2.674      0.61     -57    33
# Comp:  2             [SII]6731      1.787      0.61     -57    33
# Comp:  2              HeII4687      1.176      0.61     -57    33
# Comp:  2               HeI5876      0.000      0.61     -57    33
# Comp:  2          [OIII]5007_d      2.210      0.77     -57    33
# Comp:  2            [OI]6300_d      1.672      0.77     -57    33
# Comp:  2           [NII]6583_d      2.333      0.77     -57    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        21
#  comp.  1:       -64        33
#  comp.  2:       -41        42
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.316      0.61     -64    33
# Comp:  1                Halpha      8.136      0.61     -64    33
# Comp:  2             [SII]6716      2.036      0.63     -41    42
# Comp:  2             [SII]6731      1.869      0.63     -41    42
# Comp:  2              HeII4687      1.446      0.63     -41    42
# Comp:  2               HeI5876     0.3243      0.63     -41    42
# Comp:  2          [OIII]5007_d      2.389      0.79     -41    42
# Comp:  2            [OI]6300_d      0.000      0.79     -41    42
# Comp:  2           [NII]6583_d      2.100      0.79     -41    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        64
#  comp.  1:       -66        32
#  comp.  2:       -52        70
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.860      0.61     -66    32
# Comp:  1                Halpha      8.700      0.61     -66    32
# Comp:  2             [SII]6716      2.264      0.69     -52    70
# Comp:  2             [SII]6731      2.322      0.69     -52    70
# Comp:  2              HeII4687      1.387      0.69     -52    70
# Comp:  2               HeI5876     0.1767      0.69     -52    70
# Comp:  2          [OIII]5007_d      2.645      0.87     -52    70
# Comp:  2            [OI]6300_d     0.4685      0.87     -52    70
# Comp:  2           [NII]6583_d      2.143      0.87     -52    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -68        21
#  comp.  2:       -37        56
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.870      0.59     -68    21
# Comp:  1                Halpha      7.881      0.59     -68    21
# Comp:  2             [SII]6716      2.324      0.66     -37    56
# Comp:  2             [SII]6731      2.926      0.66     -37    56
# Comp:  2              HeII4687      1.578      0.66     -37    56
# Comp:  2               HeI5876      0.000      0.66     -37    56
# Comp:  2          [OIII]5007_d      2.577      0.83     -37    56
# Comp:  2            [OI]6300_d      1.746      0.83     -37    56
# Comp:  2           [NII]6583_d      2.109      0.83     -37    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        60
#  comp.  1:       -71        19
#  comp.  2:       -49        51
# chi2/DOF: 2.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.574      0.59     -71    19
# Comp:  1                Halpha      8.429      0.59     -71    19
# Comp:  2             [SII]6716      2.053      0.65     -49    51
# Comp:  2             [SII]6731      1.853      0.65     -49    51
# Comp:  2              HeII4687      1.210      0.65     -49    51
# Comp:  2               HeI5876     0.1793      0.65     -49    51
# Comp:  2          [OIII]5007_d      2.489      0.82     -49    51
# Comp:  2            [OI]6300_d      0.000      0.82     -49    51
# Comp:  2           [NII]6583_d      2.275      0.82     -49    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        43
#  comp.  1:       -76        51
#  comp.  2:       -46        41
# chi2/DOF: 2.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.357      0.64     -76    51
# Comp:  1                Halpha      9.937      0.64     -76    51
# Comp:  2             [SII]6716      2.217      0.62     -46    41
# Comp:  2             [SII]6731      1.797      0.62     -46    41
# Comp:  2              HeII4687      1.400      0.62     -46    41
# Comp:  2               HeI5876      0.000      0.62     -46    41
# Comp:  2          [OIII]5007_d      2.676      0.79     -46    41
# Comp:  2            [OI]6300_d      0.000      0.79     -46    41
# Comp:  2           [NII]6583_d      1.962      0.79     -46    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        46
#  comp.  1:       -62         1
#  comp.  2:       -62        25
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.665      0.57     -62     1
# Comp:  1                Halpha      7.909      0.57     -62     1
# Comp:  2             [SII]6716      2.355      0.59     -62    25
# Comp:  2             [SII]6731      2.483      0.59     -62    25
# Comp:  2              HeII4687      1.072      0.59     -62    25
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.110      0.60     -74    28
# Comp:  1                Halpha      8.419      0.60     -74    28
# Comp:  2             [SII]6716      2.439      0.74     -59    88
# Comp:  2             [SII]6731      3.090      0.74     -59    88
# Comp:  2              HeII4687      1.103      0.74     -59    88
# Comp:  2               HeI5876      0.000      0.74     -59    88
# Comp:  2          [OIII]5007_d      2.789      0.94     -59    88
# Comp:  2            [OI]6300_d      0.000      0.94     -59    88
# Comp:  2           [NII]6583_d      2.177      0.94     -59    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -72        51
#  comp.  2:       -66        58
# chi2/DOF: 2.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.286      0.64     -72    51
# Comp:  1                Halpha      9.518      0.64     -72    51
# Comp:  2             [SII]6716      2.846      0.66     -66    58
# Comp:  2             [SII]6731      2.731      0.66     -66    58
# Comp:  2              HeII4687      1.159      0.66     -66    58
# Comp:  2               HeI5876      0.000      0.66     -66    58
# Comp:  2          [OIII]5007_d      3.070      0.84     -66    58
# Comp:  2            [OI]6300_d      2.011      0.84     -66    58
# Comp:  2           [NII]6583_d      2.233      0.84     -66    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        31
#  comp.  1:       -67        23
#  comp.  2:       -54        53
# chi2/DOF: 2.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.766      0.59     -67    23
# Comp:  1                Halpha      8.353      0.59     -67    23
# Comp:  2             [SII]6716      2.524      0.65     -54    53
# Comp:  2             [SII]6731      3.095      0.65     -54    53
# Comp:  2              HeII4687      1.485      0.65     -54    53
# Comp:  2               HeI5876      0.000      0.65     -54    53
# Comp:  2          [OIII]5007_d      2.748      0.82     -54    53
# Comp:  2            [OI]6300_d     0.3926      0.82     -54    53
# Comp:  2           [NII]6583_d      2.083      0.82     -54    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        85
#  comp.  1:       -72        39
#  comp.  2:       -65        61
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.241      0.62     -72    39
# Comp:  1                Halpha      9.302      0.62     -72    39
# Comp:  2             [SII]6716      2.657      0.67     -65    61
# Comp:  2             [SII]6731      3.233      0.67     -65    61
# Comp:  2              HeII4687      1.525      0.67     -65    61
# Comp:  2               HeI5876     0.1566      0.67     -65    61
# Comp:  2          [OIII]5007_d      2.684      0.85     -65    61
# Comp:  2            [OI]6300_d      0.000      0.85     -65    61
# Comp:  2           [NII]6583_d      2.537      0.85     -65    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -72        17
#  comp.  2:       -48        43
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.541      0.58     -72    17
# Comp:  1                Halpha      8.461      0.58     -72    17
# Comp:  2             [SII]6716      2.846      0.63     -48    43
# Comp:  2             [SII]6731      2.676      0.63     -48    43
# Comp:  2              HeII4687     0.8433      0.63     -48    43
# Comp:  2               HeI5876    0.02763      0.63     -48    43
# Comp:  2          [OIII]5007_d      1.803      0.79     -48    43
# Comp:  2            [OI]6300_d     0.5968      0.79     -48    43
# Comp:  2           [NII]6583_d      1.893      0.79     -48    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -72         2
#  comp.  2:       -58        36
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.749      0.57     -72     2
# Comp:  1                Halpha      7.781      0.57     -72     2
# Comp:  2             [SII]6716      2.094      0.61     -58    36
# Comp:  2             [SII]6731      2.651      0.61     -58    36
# Comp:  2              HeII4687      1.718      0.61     -58    36
# Comp:  2               HeI5876     0.3450      0.61     -58    36
# Comp:  2          [OIII]5007_d      1.758      0.77     -58    36
# Comp:  2            [OI]6300_d      0.000      0.77     -58    36
# Comp:  2           [NII]6583_d      2.452      0.77     -58    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        62
#  comp.  1:       -68        22
#  comp.  2:       -54        52
# chi2/DOF: 2.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.133      0.59     -68    22
# Comp:  1                Halpha      8.392      0.59     -68    22
# Comp:  2             [SII]6716      2.639      0.65     -54    52
# Comp:  2             [SII]6731      2.243      0.65     -54    52
# Comp:  2              HeII4687      1.373      0.65     -54    52
# Comp:  2               HeI5876    0.06798      0.65     -54    52
# Comp:  2          [OIII]5007_d      3.143      0.82     -54    52
# Comp:  2            [OI]6300_d      0.000      0.82     -54    52
# Comp:  2           [NII]6583_d      2.470      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         4
#  comp.  1:       -61        27
#  comp.  2:       -55        47
# chi2/DOF: 2.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.004      0.60     -61    27
# Comp:  1                Halpha      8.540      0.60     -61    27
# Comp:  2             [SII]6716      2.048      0.64     -55    47
# Comp:  2             [SII]6731      2.769      0.64     -55    47
# Comp:  2              HeII4687     0.6568      0.64     -55    47
# Comp:  2               HeI5876    0.09478      0.64     -55    47
# Comp:  2          [OIII]5007_d      2.211      0.80     -55    47
# Comp:  2            [OI]6300_d      0.000      0.80     -55    47
# Comp:  2           [NII]6583_d      2.381      0.80     -55    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -67        22
#  comp.  2:       -54        52
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.974      0.59     -67    22
# Comp:  1                Halpha      8.656      0.59     -67    22
# Comp:  2             [SII]6716      2.770      0.65     -54    52
# Comp:  2             [SII]6731      2.812      0.65     -54    52
# Comp:  2              HeII4687      1.443      0.65     -54    52
# Comp:  2               HeI5876     0.1768      0.65     -54    52
# Comp:  2          [OIII]5007_d      1.996      0.82     -54    52
# Comp:  2            [OI]6300_d      0.000      0.82     -54    52
# Comp:  2           [NII]6583_d      2.030      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        43
#  comp.  1:       -68        22
#  comp.  2:       -54        51
# chi2/DOF: 2.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.642      0.59     -68    22
# Comp:  1                Halpha      8.807      0.59     -68    22
# Comp:  2             [SII]6716      2.500      0.64     -54    51
# Comp:  2             [SII]6731      2.377      0.64     -54    51
# Comp:  2              HeII4687      1.182      0.64     -54    51
# Comp:  2               HeI5876     0.3366      0.64     -54    51
# Comp:  2          [OIII]5007_d      2.572      0.81     -54    51
# Comp:  2            [OI]6300_d      1.617      0.81     -54    51
# Comp:  2           [NII]6583_d      1.989      0.81     -54    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        43
#  comp.  1:       -83        47
#  comp.  2:       -57        42
# chi2/DOF: 2.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.820      0.64     -83    47
# Comp:  1                Halpha      8.638      0.64     -83    47
# Comp:  2             [SII]6716      2.780      0.62     -57    42
# Comp:  2             [SII]6731      2.089      0.62     -57    42
# Comp:  2              HeII4687      1.471      0.62     -57    42
# Comp:  2               HeI5876    0.04175      0.62     -57    42
# Comp:  2          [OIII]5007_d      2.791      0.79     -57    42
# Comp:  2            [OI]6300_d      0.000      0.79     -57    42
# Comp:  2           [NII]6583_d      1.807      0.79     -57    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        84
#  comp.  1:       -67        21
#  comp.  2:       -54        52
# chi2/DOF: 2.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.874      0.59     -67    21
# Comp:  1                Halpha      7.589      0.59     -67    21
# Comp:  2             [SII]6716      2.153      0.65     -54    52
# Comp:  2             [SII]6731      1.968      0.65     -54    52
# Comp:  2              HeII4687      1.272      0.65     -54    52
# Comp:  2               HeI5876      0.000      0.65     -54    52
# Comp:  2          [OIII]5007_d      1.881      0.82     -54    52
# Comp:  2            [OI]6300_d     0.2961      0.82     -54    52
# Comp:  2           [NII]6583_d      2.334      0.82     -54    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -72        44
#  comp.  2:       -54        46
# chi2/DOF: 2.026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.702      0.63     -72    44
# Comp:  1                Halpha      9.268      0.63     -72    44
# Comp:  2             [SII]6716      2.679      0.63     -54    46
# Comp:  2             [SII]6731      2.104      0.63     -54    46
# Comp:  2              HeII4687      1.363      0.63     -54    46
# Comp:  2               HeI5876     0.1304      0.63     -54    46
# Comp:  2          [OIII]5007_d      2.827      0.80     -54    46
# Comp:  2            [OI]6300_d      0.000      0.80     -54    46
# Comp:  2           [NII]6583_d      2.077      0.80     -54    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -70         9
#  comp.  2:       -57        43
# chi2/DOF: 2.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.004      0.58     -70     9
# Comp:  1                Halpha      8.459      0.58     -70     9
# Comp:  2             [SII]6716      2.191      0.63     -57    43
# Comp:  2             [SII]6731      2.638      0.63     -57    43
# Comp:  2              HeII4687      1.228      0.63     -57    43
# Comp:  2               HeI5876     0.1335      0.63     -57    43
# Comp:  2          [OIII]5007_d      2.636      0.79     -57    43
# Comp:  2            [OI]6300_d     0.4092      0.79     -57    43
# Comp:  2           [NII]6583_d      2.106      0.79     -57    43
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.87494774, 0.68906396, 0.4445197 , 0.5093352 , 0.35372931,
#        0.16651968, 0.43201222, 0.76296698, 0.33374374])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.44771042, 11.12949925,  3.28590905,  3.43309834,  1.11818997,
#         0.12648275,  2.67954923,  0.        ,  2.88864261])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_14_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_14", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_14_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_14_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_14_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.075157    0.014785
# 1        Halpha  0.188065    0.011644
# 2     [SII]6716  0.055525    0.007511
# 3     [SII]6731  0.058012    0.008607
# 4      HeII4687  0.018895    0.005977
# 5       HeI5876  0.002137    0.002814
# 6  [OIII]5007_d  0.045279    0.007300
# 7    [OI]6300_d  0.000000    0.012893
# 8   [NII]6583_d  0.048812    0.005640
#           Name      Flux  Error_flux
# 0        Hbeta  0.075157    0.014785
# 1       Halpha  0.188065    0.011644
# 2    [SII]6716  0.055525    0.007511
# 3    [SII]6731  0.058012    0.008607
# 4     HeII4687  0.018895    0.005977
# 5      HeI5876  0.002137    0.002814
# 6   [OIII]4959  0.011320    0.007300
# 7   [OIII]5007  0.033959    0.007300
# 8     [OI]6300  0.000000    0.012893
# 9     [OI]6364  0.000000    0.012893
# 10   [NII]6548  0.012203    0.005640
# 11   [NII]6583  0.036609    0.005640

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0168979122751005
