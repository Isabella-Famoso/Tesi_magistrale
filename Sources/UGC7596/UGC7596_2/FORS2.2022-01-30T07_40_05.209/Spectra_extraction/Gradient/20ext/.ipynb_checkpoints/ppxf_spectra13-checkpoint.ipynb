# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_13.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_13']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.03271543 0.0330051  0.03214602 ... 0.02677166 0.01985168 0.01719173] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
# chi2/DOF: 0.06536; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        12
# chi2/DOF: 0.02597; DOF: 1913; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-37.38581034,  12.12088277])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -57        25
#  comp.  2:       -68        63
# chi2/DOF: 1.444; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.268      0.41     -57    25
# Comp:  1                Halpha      8.074      0.41     -57    25
# Comp:  2             [SII]6716      2.335      0.47     -68    63
# Comp:  2             [SII]6731      1.750      0.47     -68    63
# Comp:  2              HeII4687      0.000      0.47     -68    63
# Comp:  2               HeI5876      0.000      0.47     -68    63
# Comp:  2          [OIII]5007_d      3.839      0.59     -68    63
# Comp:  2            [OI]6300_d     0.5140      0.59     -68    63
# Comp:  2           [NII]6583_d      2.586      0.59     -68    63
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  6.448; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  16.73; gas flux:     11 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  3.874; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   2.84; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  4.688; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.6175; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.204; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -55        38
#  comp.  2:       -85        64
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.543      0.43     -55    38
# Comp:  1                Halpha      8.503      0.43     -55    38
# Comp:  2             [SII]6716      2.421      0.47     -85    64
# Comp:  2             [SII]6731      1.908      0.47     -85    64
# Comp:  2              HeII4687     0.2546      0.47     -85    64
# Comp:  2               HeI5876     0.2146      0.47     -85    64
# Comp:  2          [OIII]5007_d      3.485      0.59     -85    64
# Comp:  2            [OI]6300_d     0.2519      0.59     -85    64
# Comp:  2           [NII]6583_d      2.959      0.59     -85    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        38
#  comp.  1:       -57        26
#  comp.  2:       -68        63
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.042      0.41     -57    26
# Comp:  1                Halpha      8.600      0.41     -57    26
# Comp:  2             [SII]6716      2.406      0.47     -68    63
# Comp:  2             [SII]6731      2.269      0.47     -68    63
# Comp:  2              HeII4687     0.4576      0.47     -68    63
# Comp:  2               HeI5876     0.3934      0.47     -68    63
# Comp:  2          [OIII]5007_d      4.070      0.59     -68    63
# Comp:  2            [OI]6300_d     0.7271      0.59     -68    63
# Comp:  2           [NII]6583_d      2.451      0.59     -68    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -56        21
#  comp.  2:       -73        51
# chi2/DOF: 1.440; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.424      0.41     -56    21
# Comp:  1                Halpha      8.075      0.41     -56    21
# Comp:  2             [SII]6716      2.186      0.44     -73    51
# Comp:  2             [SII]6731      1.145      0.44     -73    51
# Comp:  2              HeII4687      0.000      0.44     -73    51
# Comp:  2               HeI5876      0.000      0.44     -73    51
# Comp:  2          [OIII]5007_d      3.834      0.56     -73    51
# Comp:  2            [OI]6300_d     0.7748      0.56     -73    51
# Comp:  2           [NII]6583_d      2.371      0.56     -73    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -57        37
#  comp.  2:       -55        74
# chi2/DOF: 1.430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.378      0.42     -57    37
# Comp:  1                Halpha      9.121      0.42     -57    37
# Comp:  2             [SII]6716      2.586      0.48     -55    74
# Comp:  2             [SII]6731      1.953      0.48     -55    74
# Comp:  2              HeII4687      0.000      0.48     -55    74
# Comp:  2               HeI5876     0.3996      0.48     -55    74
# Comp:  2          [OIII]5007_d      3.823      0.61     -55    74
# Comp:  2            [OI]6300_d   0.009435      0.61     -55    74
# Comp:  2           [NII]6583_d      2.590      0.61     -55    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         8
#  comp.  1:       -59        36
#  comp.  2:       -71        66
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.028      0.42     -59    36
# Comp:  1                Halpha      8.215      0.42     -59    36
# Comp:  2             [SII]6716      2.365      0.47     -71    66
# Comp:  2             [SII]6731      1.180      0.47     -71    66
# Comp:  2              HeII4687      0.000      0.47     -71    66
# Comp:  2               HeI5876      0.000      0.47     -71    66
# Comp:  2          [OIII]5007_d      4.119      0.59     -71    66
# Comp:  2            [OI]6300_d     0.5941      0.59     -71    66
# Comp:  2           [NII]6583_d      2.595      0.59     -71    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -58        28
#  comp.  2:       -51        72
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.444      0.41     -58    28
# Comp:  1                Halpha      8.064      0.41     -58    28
# Comp:  2             [SII]6716      2.370      0.48     -51    72
# Comp:  2             [SII]6731      2.120      0.48     -51    72
# Comp:  2              HeII4687     0.1521      0.48     -51    72
# Comp:  2               HeI5876     0.2011      0.48     -51    72
# Comp:  2          [OIII]5007_d      3.814      0.61     -51    72
# Comp:  2            [OI]6300_d     0.7433      0.61     -51    72
# Comp:  2           [NII]6583_d      2.565      0.61     -51    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        48
#  comp.  1:       -57        25
#  comp.  2:       -68        63
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.601      0.41     -57    25
# Comp:  1                Halpha      7.869      0.41     -57    25
# Comp:  2             [SII]6716      2.025      0.47     -68    63
# Comp:  2             [SII]6731      2.118      0.47     -68    63
# Comp:  2              HeII4687      0.000      0.47     -68    63
# Comp:  2               HeI5876      0.000      0.47     -68    63
# Comp:  2          [OIII]5007_d      3.589      0.59     -68    63
# Comp:  2            [OI]6300_d     0.8746      0.59     -68    63
# Comp:  2           [NII]6583_d      2.205      0.59     -68    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -59        32
#  comp.  2:       -57        69
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.060      0.42     -59    32
# Comp:  1                Halpha      8.423      0.42     -59    32
# Comp:  2             [SII]6716      2.596      0.48     -57    69
# Comp:  2             [SII]6731      1.726      0.48     -57    69
# Comp:  2              HeII4687      0.000      0.48     -57    69
# Comp:  2               HeI5876     0.2606      0.48     -57    69
# Comp:  2          [OIII]5007_d      3.614      0.60     -57    69
# Comp:  2            [OI]6300_d     0.2417      0.60     -57    69
# Comp:  2           [NII]6583_d      2.247      0.60     -57    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        31
#  comp.  1:       -57        26
#  comp.  2:       -68        63
# chi2/DOF: 1.440; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.341      0.41     -57    26
# Comp:  1                Halpha      8.149      0.41     -57    26
# Comp:  2             [SII]6716      2.353      0.47     -68    63
# Comp:  2             [SII]6731      1.796      0.47     -68    63
# Comp:  2              HeII4687      0.000      0.47     -68    63
# Comp:  2               HeI5876     0.2520      0.47     -68    63
# Comp:  2          [OIII]5007_d      3.953      0.59     -68    63
# Comp:  2            [OI]6300_d     0.6550      0.59     -68    63
# Comp:  2           [NII]6583_d      2.738      0.59     -68    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -58        24
#  comp.  2:       -69        56
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.550      0.41     -58    24
# Comp:  1                Halpha      8.134      0.41     -58    24
# Comp:  2             [SII]6716      2.104      0.45     -69    56
# Comp:  2             [SII]6731      1.508      0.45     -69    56
# Comp:  2              HeII4687     0.1303      0.45     -69    56
# Comp:  2               HeI5876     0.4046      0.45     -69    56
# Comp:  2          [OIII]5007_d      3.952      0.57     -69    56
# Comp:  2            [OI]6300_d      1.235      0.57     -69    56
# Comp:  2           [NII]6583_d      2.565      0.57     -69    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        25
#  comp.  1:       -56        34
#  comp.  2:       -70        53
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.289      0.42     -56    34
# Comp:  1                Halpha      8.630      0.42     -56    34
# Comp:  2             [SII]6716      2.022      0.45     -70    53
# Comp:  2             [SII]6731      1.426      0.45     -70    53
# Comp:  2              HeII4687      0.000      0.45     -70    53
# Comp:  2               HeI5876     0.1480      0.45     -70    53
# Comp:  2          [OIII]5007_d      3.689      0.57     -70    53
# Comp:  2            [OI]6300_d     0.5811      0.57     -70    53
# Comp:  2           [NII]6583_d      2.108      0.57     -70    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -54        20
#  comp.  2:       -72        48
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.707      0.40     -54    20
# Comp:  1                Halpha      7.938      0.40     -54    20
# Comp:  2             [SII]6716      2.015      0.44     -72    48
# Comp:  2             [SII]6731      1.090      0.44     -72    48
# Comp:  2              HeII4687      0.000      0.44     -72    48
# Comp:  2               HeI5876      0.000      0.44     -72    48
# Comp:  2          [OIII]5007_d      3.838      0.56     -72    48
# Comp:  2            [OI]6300_d     0.5854      0.56     -72    48
# Comp:  2           [NII]6583_d      2.591      0.56     -72    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -56        20
#  comp.  2:       -69        68
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.521      0.41     -56    20
# Comp:  1                Halpha      8.014      0.41     -56    20
# Comp:  2             [SII]6716      2.286      0.47     -69    68
# Comp:  2             [SII]6731      2.030      0.47     -69    68
# Comp:  2              HeII4687     0.1606      0.47     -69    68
# Comp:  2               HeI5876     0.3585      0.47     -69    68
# Comp:  2          [OIII]5007_d      4.135      0.60     -69    68
# Comp:  2            [OI]6300_d     0.9972      0.60     -69    68
# Comp:  2           [NII]6583_d      2.386      0.60     -69    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1         1
#  comp.  1:       -57        38
#  comp.  2:       -71        63
# chi2/DOF: 1.429; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.456      0.43     -57    38
# Comp:  1                Halpha      8.483      0.43     -57    38
# Comp:  2             [SII]6716      2.311      0.47     -71    63
# Comp:  2             [SII]6731      1.472      0.47     -71    63
# Comp:  2              HeII4687      0.000      0.47     -71    63
# Comp:  2               HeI5876      0.000      0.47     -71    63
# Comp:  2          [OIII]5007_d      3.947      0.59     -71    63
# Comp:  2            [OI]6300_d     0.5938      0.59     -71    63
# Comp:  2           [NII]6583_d      2.735      0.59     -71    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        19
#  comp.  1:       -58        41
#  comp.  2:       -67        61
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.309      0.43     -58    41
# Comp:  1                Halpha      8.726      0.43     -58    41
# Comp:  2             [SII]6716      2.312      0.46     -67    61
# Comp:  2             [SII]6731      1.678      0.46     -67    61
# Comp:  2              HeII4687      0.000      0.46     -67    61
# Comp:  2               HeI5876      0.000      0.46     -67    61
# Comp:  2          [OIII]5007_d      3.927      0.58     -67    61
# Comp:  2            [OI]6300_d     0.4198      0.58     -67    61
# Comp:  2           [NII]6583_d      2.657      0.58     -67    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -56        28
#  comp.  2:       -65        72
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.826      0.41     -56    28
# Comp:  1                Halpha      8.226      0.41     -56    28
# Comp:  2             [SII]6716      2.672      0.48     -65    72
# Comp:  2             [SII]6731      1.565      0.48     -65    72
# Comp:  2              HeII4687      0.000      0.48     -65    72
# Comp:  2               HeI5876     0.1175      0.48     -65    72
# Comp:  2          [OIII]5007_d      3.996      0.61     -65    72
# Comp:  2            [OI]6300_d     0.4132      0.61     -65    72
# Comp:  2           [NII]6583_d      2.789      0.61     -65    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        36
#  comp.  1:       -58        25
#  comp.  2:       -69        62
# chi2/DOF: 1.441; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.344      0.41     -58    25
# Comp:  1                Halpha      8.370      0.41     -58    25
# Comp:  2             [SII]6716      2.337      0.46     -69    62
# Comp:  2             [SII]6731      1.560      0.46     -69    62
# Comp:  2              HeII4687      0.000      0.46     -69    62
# Comp:  2               HeI5876    0.08131      0.46     -69    62
# Comp:  2          [OIII]5007_d      3.630      0.59     -69    62
# Comp:  2            [OI]6300_d     0.9349      0.59     -69    62
# Comp:  2           [NII]6583_d      2.711      0.59     -69    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        79
#  comp.  1:       -60        35
#  comp.  2:       -75        79
# chi2/DOF: 1.430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.092      0.42     -60    35
# Comp:  1                Halpha      8.197      0.42     -60    35
# Comp:  2             [SII]6716      2.404      0.49     -75    79
# Comp:  2             [SII]6731      2.398      0.49     -75    79
# Comp:  2              HeII4687      0.000      0.49     -75    79
# Comp:  2               HeI5876     0.1766      0.49     -75    79
# Comp:  2          [OIII]5007_d      3.955      0.62     -75    79
# Comp:  2            [OI]6300_d     0.2912      0.62     -75    79
# Comp:  2           [NII]6583_d      2.562      0.62     -75    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -55        20
#  comp.  2:       -77        69
# chi2/DOF: 1.428; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.413      0.41     -55    20
# Comp:  1                Halpha      8.142      0.41     -55    20
# Comp:  2             [SII]6716      2.436      0.48     -77    69
# Comp:  2             [SII]6731      1.534      0.48     -77    69
# Comp:  2              HeII4687      0.000      0.48     -77    69
# Comp:  2               HeI5876      0.000      0.48     -77    69
# Comp:  2          [OIII]5007_d      3.670      0.60     -77    69
# Comp:  2            [OI]6300_d     0.6618      0.60     -77    69
# Comp:  2           [NII]6583_d      2.958      0.60     -77    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -61        33
#  comp.  2:       -64        54
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.596      0.42     -61    33
# Comp:  1                Halpha      8.466      0.42     -61    33
# Comp:  2             [SII]6716      2.239      0.45     -64    54
# Comp:  2             [SII]6731      1.877      0.45     -64    54
# Comp:  2              HeII4687      0.000      0.45     -64    54
# Comp:  2               HeI5876     0.2003      0.45     -64    54
# Comp:  2          [OIII]5007_d      3.546      0.57     -64    54
# Comp:  2            [OI]6300_d     0.7266      0.57     -64    54
# Comp:  2           [NII]6583_d      2.306      0.57     -64    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -53        21
#  comp.  2:       -73        80
# chi2/DOF: 1.431; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.563      0.41     -53    21
# Comp:  1                Halpha      7.977      0.41     -53    21
# Comp:  2             [SII]6716      2.490      0.50     -73    80
# Comp:  2             [SII]6731      1.758      0.50     -73    80
# Comp:  2              HeII4687     0.1095      0.50     -73    80
# Comp:  2               HeI5876      0.000      0.50     -73    80
# Comp:  2          [OIII]5007_d      3.837      0.63     -73    80
# Comp:  2            [OI]6300_d      1.207      0.63     -73    80
# Comp:  2           [NII]6583_d      2.907      0.63     -73    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -60        34
#  comp.  2:       -60        63
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.086      0.42     -60    34
# Comp:  1                Halpha      8.361      0.42     -60    34
# Comp:  2             [SII]6716      2.349      0.47     -60    63
# Comp:  2             [SII]6731      1.141      0.47     -60    63
# Comp:  2              HeII4687    0.02412      0.47     -60    63
# Comp:  2               HeI5876      0.000      0.47     -60    63
# Comp:  2          [OIII]5007_d      3.613      0.59     -60    63
# Comp:  2            [OI]6300_d     0.3129      0.59     -60    63
# Comp:  2           [NII]6583_d      2.537      0.59     -60    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        37
#  comp.  1:       -57        26
#  comp.  2:       -68        64
# chi2/DOF: 1.432; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.060      0.41     -57    26
# Comp:  1                Halpha      8.103      0.41     -57    26
# Comp:  2             [SII]6716      2.231      0.47     -68    64
# Comp:  2             [SII]6731      1.627      0.47     -68    64
# Comp:  2              HeII4687      0.000      0.47     -68    64
# Comp:  2               HeI5876     0.3248      0.47     -68    64
# Comp:  2          [OIII]5007_d      3.585      0.59     -68    64
# Comp:  2            [OI]6300_d     0.3044      0.59     -68    64
# Comp:  2           [NII]6583_d      2.591      0.59     -68    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        28
#  comp.  1:       -57        24
#  comp.  2:       -68        62
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.452      0.41     -57    24
# Comp:  1                Halpha      8.218      0.41     -57    24
# Comp:  2             [SII]6716      2.178      0.46     -68    62
# Comp:  2             [SII]6731      1.530      0.46     -68    62
# Comp:  2              HeII4687      0.000      0.46     -68    62
# Comp:  2               HeI5876      0.000      0.46     -68    62
# Comp:  2          [OIII]5007_d      4.112      0.59     -68    62
# Comp:  2            [OI]6300_d      0.000      0.59     -68    62
# Comp:  2           [NII]6583_d      2.747      0.59     -68    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        82
#  comp.  1:       -59        36
#  comp.  2:       -54        53
# chi2/DOF: 1.431; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.923      0.42     -59    36
# Comp:  1                Halpha      8.634      0.42     -59    36
# Comp:  2             [SII]6716      2.302      0.45     -54    53
# Comp:  2             [SII]6731      1.801      0.45     -54    53
# Comp:  2              HeII4687      0.000      0.45     -54    53
# Comp:  2               HeI5876     0.1079      0.45     -54    53
# Comp:  2          [OIII]5007_d      3.796      0.57     -54    53
# Comp:  2            [OI]6300_d      0.000      0.57     -54    53
# Comp:  2           [NII]6583_d      2.737      0.57     -54    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -58        17
#  comp.  2:       -69        52
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.449      0.40     -58    17
# Comp:  1                Halpha      7.997      0.40     -58    17
# Comp:  2             [SII]6716      2.420      0.45     -69    52
# Comp:  2             [SII]6731      1.556      0.45     -69    52
# Comp:  2              HeII4687      0.000      0.45     -69    52
# Comp:  2               HeI5876      0.000      0.45     -69    52
# Comp:  2          [OIII]5007_d      4.054      0.56     -69    52
# Comp:  2            [OI]6300_d      1.137      0.56     -69    52
# Comp:  2           [NII]6583_d      2.424      0.56     -69    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -53        31
#  comp.  2:       -75        76
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.686      0.42     -53    31
# Comp:  1                Halpha      8.021      0.42     -53    31
# Comp:  2             [SII]6716      2.550      0.49     -75    76
# Comp:  2             [SII]6731      1.920      0.49     -75    76
# Comp:  2              HeII4687      0.000      0.49     -75    76
# Comp:  2               HeI5876      0.000      0.49     -75    76
# Comp:  2          [OIII]5007_d      3.771      0.62     -75    76
# Comp:  2            [OI]6300_d     0.6405      0.62     -75    76
# Comp:  2           [NII]6583_d      3.270      0.62     -75    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         9
#  comp.  1:       -63        32
#  comp.  2:       -81        66
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.184      0.42     -63    32
# Comp:  1                Halpha      8.680      0.42     -63    32
# Comp:  2             [SII]6716      2.605      0.47     -81    66
# Comp:  2             [SII]6731      1.442      0.47     -81    66
# Comp:  2              HeII4687     0.2198      0.47     -81    66
# Comp:  2               HeI5876     0.5130      0.47     -81    66
# Comp:  2          [OIII]5007_d      3.644      0.60     -81    66
# Comp:  2            [OI]6300_d     0.6823      0.60     -81    66
# Comp:  2           [NII]6583_d      2.521      0.60     -81    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83       214
#  comp.  1:       -61        36
#  comp.  2:       -57        62
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.501      0.42     -61    36
# Comp:  1                Halpha      8.211      0.42     -61    36
# Comp:  2             [SII]6716      2.357      0.46     -57    62
# Comp:  2             [SII]6731      1.935      0.46     -57    62
# Comp:  2              HeII4687     0.1112      0.46     -57    62
# Comp:  2               HeI5876     0.1598      0.46     -57    62
# Comp:  2          [OIII]5007_d      3.476      0.59     -57    62
# Comp:  2            [OI]6300_d     0.6711      0.59     -57    62
# Comp:  2           [NII]6583_d      2.593      0.59     -57    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -60        29
#  comp.  2:       -59        68
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.937      0.41     -60    29
# Comp:  1                Halpha      8.348      0.41     -60    29
# Comp:  2             [SII]6716      2.633      0.48     -59    68
# Comp:  2             [SII]6731      1.883      0.48     -59    68
# Comp:  2              HeII4687      0.000      0.48     -59    68
# Comp:  2               HeI5876      0.000      0.48     -59    68
# Comp:  2          [OIII]5007_d      4.063      0.60     -59    68
# Comp:  2            [OI]6300_d     0.5219      0.60     -59    68
# Comp:  2           [NII]6583_d      2.711      0.60     -59    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -59        35
#  comp.  2:       -73        63
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.779      0.42     -59    35
# Comp:  1                Halpha      8.433      0.42     -59    35
# Comp:  2             [SII]6716      2.471      0.47     -73    63
# Comp:  2             [SII]6731      1.411      0.47     -73    63
# Comp:  2              HeII4687     0.5160      0.47     -73    63
# Comp:  2               HeI5876      0.000      0.47     -73    63
# Comp:  2          [OIII]5007_d      3.923      0.59     -73    63
# Comp:  2            [OI]6300_d     0.2310      0.59     -73    63
# Comp:  2           [NII]6583_d      2.801      0.59     -73    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -56        34
#  comp.  2:       -62        60
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.160      0.42     -56    34
# Comp:  1                Halpha      8.667      0.42     -56    34
# Comp:  2             [SII]6716      2.231      0.46     -62    60
# Comp:  2             [SII]6731      2.194      0.46     -62    60
# Comp:  2              HeII4687      0.000      0.46     -62    60
# Comp:  2               HeI5876      0.000      0.46     -62    60
# Comp:  2          [OIII]5007_d      3.934      0.58     -62    60
# Comp:  2            [OI]6300_d     0.4526      0.58     -62    60
# Comp:  2           [NII]6583_d      2.579      0.58     -62    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -59        36
#  comp.  2:       -64        50
# chi2/DOF: 1.433; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.156      0.42     -59    36
# Comp:  1                Halpha      8.574      0.42     -59    36
# Comp:  2             [SII]6716      1.861      0.44     -64    50
# Comp:  2             [SII]6731      1.938      0.44     -64    50
# Comp:  2              HeII4687     0.2201      0.44     -64    50
# Comp:  2               HeI5876     0.1964      0.44     -64    50
# Comp:  2          [OIII]5007_d      3.219      0.56     -64    50
# Comp:  2            [OI]6300_d     0.6488      0.56     -64    50
# Comp:  2           [NII]6583_d      2.386      0.56     -64    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -55        27
#  comp.  2:       -60        45
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.023      0.41     -55    27
# Comp:  1                Halpha      8.622      0.41     -55    27
# Comp:  2             [SII]6716      1.914      0.44     -60    45
# Comp:  2             [SII]6731      1.849      0.44     -60    45
# Comp:  2              HeII4687      0.000      0.44     -60    45
# Comp:  2               HeI5876     0.4349      0.44     -60    45
# Comp:  2          [OIII]5007_d      3.802      0.55     -60    45
# Comp:  2            [OI]6300_d     0.6150      0.55     -60    45
# Comp:  2           [NII]6583_d      2.209      0.55     -60    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        57
#  comp.  1:       -55        18
#  comp.  2:       -67        80
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.938      0.40     -55    18
# Comp:  1                Halpha      7.814      0.40     -55    18
# Comp:  2             [SII]6716      2.265      0.50     -67    80
# Comp:  2             [SII]6731      2.196      0.50     -67    80
# Comp:  2              HeII4687     0.3516      0.50     -67    80
# Comp:  2               HeI5876     0.3778      0.50     -67    80
# Comp:  2          [OIII]5007_d      4.178      0.63     -67    80
# Comp:  2            [OI]6300_d      1.068      0.63     -67    80
# Comp:  2           [NII]6583_d      2.819      0.63     -67    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        87
#  comp.  1:       -55        19
#  comp.  2:       -69        84
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.410      0.40     -55    19
# Comp:  1                Halpha      8.110      0.40     -55    19
# Comp:  2             [SII]6716      2.575      0.50     -69    84
# Comp:  2             [SII]6731      2.296      0.50     -69    84
# Comp:  2              HeII4687     0.7264      0.50     -69    84
# Comp:  2               HeI5876      0.000      0.50     -69    84
# Comp:  2          [OIII]5007_d      4.227      0.64     -69    84
# Comp:  2            [OI]6300_d     0.1593      0.64     -69    84
# Comp:  2           [NII]6583_d      2.766      0.64     -69    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        58
#  comp.  1:       -57        25
#  comp.  2:       -68        64
# chi2/DOF: 1.434; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.074      0.41     -57    25
# Comp:  1                Halpha      8.296      0.41     -57    25
# Comp:  2             [SII]6716      2.292      0.47     -68    64
# Comp:  2             [SII]6731      1.907      0.47     -68    64
# Comp:  2              HeII4687     0.4470      0.47     -68    64
# Comp:  2               HeI5876      0.000      0.47     -68    64
# Comp:  2          [OIII]5007_d      3.533      0.59     -68    64
# Comp:  2            [OI]6300_d     0.8777      0.59     -68    64
# Comp:  2           [NII]6583_d      2.475      0.59     -68    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -53        22
#  comp.  2:       -68        45
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.406      0.41     -53    22
# Comp:  1                Halpha      7.686      0.41     -53    22
# Comp:  2             [SII]6716      2.181      0.44     -68    45
# Comp:  2             [SII]6731      2.012      0.44     -68    45
# Comp:  2              HeII4687      0.000      0.44     -68    45
# Comp:  2               HeI5876     0.2944      0.44     -68    45
# Comp:  2          [OIII]5007_d      3.736      0.55     -68    45
# Comp:  2            [OI]6300_d     0.4344      0.55     -68    45
# Comp:  2           [NII]6583_d      2.406      0.55     -68    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -52        29
#  comp.  2:       -75        61
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.041      0.41     -52    29
# Comp:  1                Halpha      8.037      0.41     -52    29
# Comp:  2             [SII]6716      2.166      0.46     -75    61
# Comp:  2             [SII]6731      1.300      0.46     -75    61
# Comp:  2              HeII4687     0.4639      0.46     -75    61
# Comp:  2               HeI5876    0.04722      0.46     -75    61
# Comp:  2          [OIII]5007_d      3.405      0.58     -75    61
# Comp:  2            [OI]6300_d     0.4625      0.58     -75    61
# Comp:  2           [NII]6583_d      2.522      0.58     -75    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        28
#  comp.  1:       -57        24
#  comp.  2:       -68        63
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.864      0.41     -57    24
# Comp:  1                Halpha      8.046      0.41     -57    24
# Comp:  2             [SII]6716      2.266      0.47     -68    63
# Comp:  2             [SII]6731      1.952      0.47     -68    63
# Comp:  2              HeII4687    0.01235      0.47     -68    63
# Comp:  2               HeI5876      0.000      0.47     -68    63
# Comp:  2          [OIII]5007_d      3.867      0.59     -68    63
# Comp:  2            [OI]6300_d      0.000      0.59     -68    63
# Comp:  2           [NII]6583_d      2.370      0.59     -68    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -54        26
#  comp.  2:       -55        70
# chi2/DOF: 1.432; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.634      0.41     -54    26
# Comp:  1                Halpha      8.440      0.41     -54    26
# Comp:  2             [SII]6716      2.590      0.48     -55    70
# Comp:  2             [SII]6731      2.005      0.48     -55    70
# Comp:  2              HeII4687      0.000      0.48     -55    70
# Comp:  2               HeI5876      0.000      0.48     -55    70
# Comp:  2          [OIII]5007_d      4.164      0.60     -55    70
# Comp:  2            [OI]6300_d      1.018      0.60     -55    70
# Comp:  2           [NII]6583_d      2.624      0.60     -55    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        28
#  comp.  1:       -57        25
#  comp.  2:       -68        64
# chi2/DOF: 1.439; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.627      0.41     -57    25
# Comp:  1                Halpha      7.909      0.41     -57    25
# Comp:  2             [SII]6716      2.162      0.47     -68    64
# Comp:  2             [SII]6731      2.091      0.47     -68    64
# Comp:  2              HeII4687     0.3957      0.47     -68    64
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.383      0.40     -59    19
# Comp:  1                Halpha      8.006      0.40     -59    19
# Comp:  2             [SII]6716      2.106      0.43     -75    43
# Comp:  2             [SII]6731      1.626      0.43     -75    43
# Comp:  2              HeII4687      0.000      0.43     -75    43
# Comp:  2               HeI5876      0.000      0.43     -75    43
# Comp:  2          [OIII]5007_d      3.424      0.55     -75    43
# Comp:  2            [OI]6300_d     0.4296      0.55     -75    43
# Comp:  2           [NII]6583_d      2.604      0.55     -75    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -56        33
#  comp.  2:       -72        71
# chi2/DOF: 1.427; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.009      0.42     -56    33
# Comp:  1                Halpha      8.512      0.42     -56    33
# Comp:  2             [SII]6716      2.219      0.48     -72    71
# Comp:  2             [SII]6731      2.094      0.48     -72    71
# Comp:  2              HeII4687      0.000      0.48     -72    71
# Comp:  2               HeI5876      0.000      0.48     -72    71
# Comp:  2          [OIII]5007_d      4.295      0.61     -72    71
# Comp:  2            [OI]6300_d     0.7611      0.61     -72    71
# Comp:  2           [NII]6583_d      2.648      0.61     -72    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        42
#  comp.  1:       -52        24
#  comp.  2:       -71        63
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.785      0.41     -52    24
# Comp:  1                Halpha      8.483      0.41     -52    24
# Comp:  2             [SII]6716      2.203      0.47     -71    63
# Comp:  2             [SII]6731      1.539      0.47     -71    63
# Comp:  2              HeII4687      0.000      0.47     -71    63
# Comp:  2               HeI5876      0.000      0.47     -71    63
# Comp:  2          [OIII]5007_d      3.914      0.59     -71    63
# Comp:  2            [OI]6300_d     0.7042      0.59     -71    63
# Comp:  2           [NII]6583_d      2.488      0.59     -71    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -55        31
#  comp.  2:       -60        65
# chi2/DOF: 1.435; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.175      0.42     -55    31
# Comp:  1                Halpha      8.413      0.42     -55    31
# Comp:  2             [SII]6716      2.359      0.47     -60    65
# Comp:  2             [SII]6731      1.589      0.47     -60    65
# Comp:  2              HeII4687      0.000      0.47     -60    65
# Comp:  2               HeI5876     0.7442      0.47     -60    65
# Comp:  2          [OIII]5007_d      4.224      0.59     -60    65
# Comp:  2            [OI]6300_d      1.334      0.59     -60    65
# Comp:  2           [NII]6583_d      2.559      0.59     -60    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       121
#  comp.  1:       -57        26
#  comp.  2:       -69        64
# chi2/DOF: 1.437; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.244      0.41     -57    26
# Comp:  1                Halpha      7.823      0.41     -57    26
# Comp:  2             [SII]6716      2.137      0.47     -69    64
# Comp:  2             [SII]6731      1.328      0.47     -69    64
# Comp:  2              HeII4687      0.000      0.47     -69    64
# Comp:  2               HeI5876     0.2865      0.47     -69    64
# Comp:  2          [OIII]5007_d      3.474      0.59     -69    64
# Comp:  2            [OI]6300_d      0.000      0.59     -69    64
# Comp:  2           [NII]6583_d      2.552      0.59     -69    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        12
#  comp.  1:       -62        31
#  comp.  2:       -55        84
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.021      0.42     -62    31
# Comp:  1                Halpha      8.223      0.42     -62    31
# Comp:  2             [SII]6716      2.647      0.50     -55    84
# Comp:  2             [SII]6731      2.144      0.50     -55    84
# Comp:  2              HeII4687     0.5045      0.50     -55    84
# Comp:  2               HeI5876   0.003094      0.50     -55    84
# Comp:  2          [OIII]5007_d      4.087      0.64     -55    84
# Comp:  2            [OI]6300_d      0.000      0.64     -55    84
# Comp:  2           [NII]6583_d      2.560      0.64     -55    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        91
#  comp.  1:       -58        24
#  comp.  2:       -67        64
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.331      0.41     -58    24
# Comp:  1                Halpha      8.082      0.41     -58    24
# Comp:  2             [SII]6716      2.395      0.47     -67    64
# Comp:  2             [SII]6731      2.056      0.47     -67    64
# Comp:  2              HeII4687    0.02968      0.47     -67    64
# Comp:  2               HeI5876      0.000      0.47     -67    64
# Comp:  2          [OIII]5007_d      4.100      0.59     -67    64
# Comp:  2            [OI]6300_d      1.104      0.59     -67    64
# Comp:  2           [NII]6583_d      2.631      0.59     -67    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -58        34
#  comp.  2:       -67        66
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.919      0.42     -58    34
# Comp:  1                Halpha      8.726      0.42     -58    34
# Comp:  2             [SII]6716      2.482      0.47     -67    66
# Comp:  2             [SII]6731      1.915      0.47     -67    66
# Comp:  2              HeII4687      0.000      0.47     -67    66
# Comp:  2               HeI5876     0.1640      0.47     -67    66
# Comp:  2          [OIII]5007_d      3.815      0.60     -67    66
# Comp:  2            [OI]6300_d      0.000      0.60     -67    66
# Comp:  2           [NII]6583_d      2.774      0.60     -67    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -57        38
#  comp.  2:       -64        62
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.075      0.43     -57    38
# Comp:  1                Halpha      8.562      0.43     -57    38
# Comp:  2             [SII]6716      2.258      0.46     -64    62
# Comp:  2             [SII]6731      1.906      0.46     -64    62
# Comp:  2              HeII4687      0.000      0.46     -64    62
# Comp:  2               HeI5876     0.1385      0.46     -64    62
# Comp:  2          [OIII]5007_d      3.684      0.59     -64    62
# Comp:  2            [OI]6300_d     0.1877      0.59     -64    62
# Comp:  2           [NII]6583_d      2.374      0.59     -64    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:       -61        36
#  comp.  2:       -64        78
# chi2/DOF: 1.438; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.681      0.42     -61    36
# Comp:  1                Halpha      8.359      0.42     -61    36
# Comp:  2             [SII]6716      2.367      0.49     -64    78
# Comp:  2             [SII]6731      2.464      0.49     -64    78
# Comp:  2              HeII4687   0.007683      0.49     -64    78
# Comp:  2               HeI5876      0.000      0.49     -64    78
# Comp:  2          [OIII]5007_d      4.095      0.62     -64    78
# Comp:  2            [OI]6300_d     0.5311      0.62     -64    78
# Comp:  2           [NII]6583_d      2.882      0.62     -64    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        27
#  comp.  1:       -57        24
#  comp.  2:       -68        63
# chi2/DOF: 1.436; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.398      0.41     -57    24
# Comp:  1                Halpha      8.334      0.41     -57    24
# Comp:  2             [SII]6716      1.977      0.47     -68    63
# Comp:  2             [SII]6731      1.587      0.47     -68    63
# Comp:  2              HeII4687      0.000      0.47     -68    63
# Comp:  2               HeI5876     0.3077      0.47     -68    63
# Comp:  2          [OIII]5007_d      4.141      0.59     -68    63
# Comp:  2            [OI]6300_d     0.5642      0.59     -68    63
# Comp:  2           [NII]6583_d      2.779      0.59     -68    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        22
#  comp.  1:       -56        34
#  comp.  2:       -64        80
# chi2/DOF: 1.434; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.562      0.42     -56    34
# Comp:  1                Halpha      8.498      0.42     -56    34
# Comp:  2             [SII]6716      2.718      0.50     -64    80
# Comp:  2             [SII]6731      1.958      0.50     -64    80
# Comp:  2              HeII4687      0.000      0.50     -64    80
# Comp:  2               HeI5876    0.09322      0.50     -64    80
# Comp:  2          [OIII]5007_d      4.116      0.63     -64    80
# Comp:  2            [OI]6300_d     0.3480      0.63     -64    80
# Comp:  2           [NII]6583_d      2.591      0.63     -64    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -55        19
#  comp.  2:       -58        77
# chi2/DOF: 1.430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.296      0.40     -55    19
# Comp:  1                Halpha      8.031      0.40     -55    19
# Comp:  2             [SII]6716      2.362      0.49     -58    77
# Comp:  2             [SII]6731      2.398      0.49     -58    77
# Comp:  2              HeII4687    0.08489      0.49     -58    77
# Comp:  2               HeI5876     0.5819      0.49     -58    77
# Comp:  2          [OIII]5007_d      3.821      0.62     -58    77
# Comp:  2            [OI]6300_d     0.4781      0.62     -58    77
# Comp:  2           [NII]6583_d      3.143      0.62     -58    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:       -59        36
#  comp.  2:       -68        68
# chi2/DOF: 1.432; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.788      0.42     -59    36
# Comp:  1                Halpha      8.738      0.42     -59    36
# Comp:  2             [SII]6716      2.456      0.47     -68    68
# Comp:  2             [SII]6731      2.169      0.47     -68    68
# Comp:  2              HeII4687    0.04465      0.47     -68    68
# Comp:  2               HeI5876      0.000      0.47     -68    68
# Comp:  2          [OIII]5007_d      4.172      0.60     -68    68
# Comp:  2            [OI]6300_d     0.1451      0.60     -68    68
# Comp:  2           [NII]6583_d      3.035      0.60     -68    68
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.39553399, 0.41101713, 0.30575626, 0.45811865, 0.20034115,
#        0.23186088, 0.28614552, 0.44216104, 0.31061658])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.31331129, 11.05240378,  3.27160725,  2.45732445,  0.        ,
#         0.        ,  4.00923795,  0.67543156,  3.55126428])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_13_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_13", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_13_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_13_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_13_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.097305    0.011616
# 1        Halpha  0.324586    0.012071
# 2     [SII]6716  0.096080    0.008979
# 3     [SII]6731  0.072166    0.013454
# 4      HeII4687  0.000000    0.005884
# 5       HeI5876  0.000000    0.006809
# 6  [OIII]5007_d  0.117743    0.008403
# 7    [OI]6300_d  0.019836    0.012985
# 8   [NII]6583_d  0.104293    0.009122
#           Name      Flux  Error_flux
# 0        Hbeta  0.097305    0.011616
# 1       Halpha  0.324586    0.012071
# 2    [SII]6716  0.096080    0.008979
# 3    [SII]6731  0.072166    0.013454
# 4     HeII4687  0.000000    0.005884
# 5      HeI5876  0.000000    0.006809
# 6   [OIII]4959  0.029436    0.008403
# 7   [OIII]5007  0.088307    0.008403
# 8     [OI]6300  0.014877    0.012985
# 9     [OI]6364  0.004959    0.012985
# 10   [NII]6548  0.026073    0.009122
# 11   [NII]6583  0.078220    0.009122

# %%
np.median(flux_rf_rebin)
# Out:
# 0.029367882101280707
