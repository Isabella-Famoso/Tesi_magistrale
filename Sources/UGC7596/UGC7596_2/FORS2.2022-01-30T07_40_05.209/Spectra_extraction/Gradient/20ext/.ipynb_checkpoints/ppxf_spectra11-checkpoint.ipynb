# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_11.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_11']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.04883866 0.05097614 0.04470048 ... 0.03134825 0.02675303 0.02446547] [0.00701323 0.00701323 0.00701323 ... 0.00701323 0.00701323 0.00701323]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        65
# chi2/DOF: 0.04375; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        66
# chi2/DOF: 0.01801; DOF: 1916; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-36.35734323,  66.02473479])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        44
#  comp.  1:       -60        37
#  comp.  2:       -60        26
# chi2/DOF: 1.300; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.554      0.37     -60    37
# Comp:  1                Halpha      11.88      0.37     -60    37
# Comp:  2             [SII]6716      4.762      0.36     -60    26
# Comp:  2             [SII]6731      3.438      0.36     -60    26
# Comp:  2              HeII4687     0.3773      0.36     -60    26
# Comp:  2               HeI5876      0.000      0.36     -60    26
# Comp:  2          [OIII]5007_d      2.295      0.45     -60    26
# Comp:  2            [OI]6300_d      1.961      0.45     -60    26
# Comp:  2           [NII]6583_d      2.894      0.45     -60    26
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  7.941; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  27.58; gas flux:     16 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  11.86; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  8.041; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.9546; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   4.32; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.446; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  5.295; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        32
#  comp.  1:       -60        45
#  comp.  2:       -58        15
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.998      0.38     -60    45
# Comp:  1                Halpha      12.51      0.38     -60    45
# Comp:  2             [SII]6716      4.729      0.35     -58    15
# Comp:  2             [SII]6731      3.146      0.35     -58    15
# Comp:  2              HeII4687     0.6206      0.35     -58    15
# Comp:  2               HeI5876      0.000      0.35     -58    15
# Comp:  2          [OIII]5007_d      2.581      0.44     -58    15
# Comp:  2            [OI]6300_d      1.892      0.44     -58    15
# Comp:  2           [NII]6583_d      2.818      0.44     -58    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        43
#  comp.  1:       -64        46
#  comp.  2:       -59        20
# chi2/DOF: 1.289; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.111      0.38     -64    46
# Comp:  1                Halpha      13.08      0.38     -64    46
# Comp:  2             [SII]6716      4.921      0.35     -59    20
# Comp:  2             [SII]6731      3.138      0.35     -59    20
# Comp:  2              HeII4687     0.3994      0.35     -59    20
# Comp:  2               HeI5876     0.1832      0.35     -59    20
# Comp:  2          [OIII]5007_d      1.861      0.45     -59    20
# Comp:  2            [OI]6300_d      1.917      0.45     -59    20
# Comp:  2           [NII]6583_d      2.932      0.45     -59    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -60        29
#  comp.  2:       -63        44
# chi2/DOF: 1.289; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.188      0.36     -60    29
# Comp:  1                Halpha      11.73      0.36     -60    29
# Comp:  2             [SII]6716      5.211      0.38     -63    44
# Comp:  2             [SII]6731      3.933      0.38     -63    44
# Comp:  2              HeII4687     0.5687      0.38     -63    44
# Comp:  2               HeI5876      0.000      0.38     -63    44
# Comp:  2          [OIII]5007_d      2.905      0.48     -63    44
# Comp:  2            [OI]6300_d      2.226      0.48     -63    44
# Comp:  2           [NII]6583_d      2.902      0.48     -63    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        44
#  comp.  1:       -63        45
#  comp.  2:       -58        19
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.041      0.38     -63    45
# Comp:  1                Halpha      12.96      0.38     -63    45
# Comp:  2             [SII]6716      4.493      0.35     -58    19
# Comp:  2             [SII]6731      3.451      0.35     -58    19
# Comp:  2              HeII4687     0.4348      0.35     -58    19
# Comp:  2               HeI5876     0.2459      0.35     -58    19
# Comp:  2          [OIII]5007_d      2.384      0.45     -58    19
# Comp:  2            [OI]6300_d      1.823      0.45     -58    19
# Comp:  2           [NII]6583_d      2.824      0.45     -58    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -65        47
#  comp.  2:       -65        42
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.662      0.38     -65    47
# Comp:  1                Halpha      12.48      0.38     -65    47
# Comp:  2             [SII]6716      5.050      0.38     -65    42
# Comp:  2             [SII]6731      3.957      0.38     -65    42
# Comp:  2              HeII4687     0.3429      0.38     -65    42
# Comp:  2               HeI5876     0.1653      0.38     -65    42
# Comp:  2          [OIII]5007_d      2.919      0.48     -65    42
# Comp:  2            [OI]6300_d      2.327      0.48     -65    42
# Comp:  2           [NII]6583_d      3.214      0.48     -65    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -61        48
#  comp.  2:       -56        42
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.483      0.38     -61    48
# Comp:  1                Halpha      13.17      0.38     -61    48
# Comp:  2             [SII]6716      4.802      0.38     -56    42
# Comp:  2             [SII]6731      3.586      0.38     -56    42
# Comp:  2              HeII4687     0.2719      0.38     -56    42
# Comp:  2               HeI5876      0.000      0.38     -56    42
# Comp:  2          [OIII]5007_d      2.812      0.48     -56    42
# Comp:  2            [OI]6300_d      2.330      0.48     -56    42
# Comp:  2           [NII]6583_d      3.163      0.48     -56    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        72
#  comp.  1:       -61        33
#  comp.  2:       -59        30
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.553      0.37     -61    33
# Comp:  1                Halpha      11.66      0.37     -61    33
# Comp:  2             [SII]6716      4.974      0.36     -59    30
# Comp:  2             [SII]6731      3.277      0.36     -59    30
# Comp:  2              HeII4687     0.4113      0.36     -59    30
# Comp:  2               HeI5876      0.000      0.36     -59    30
# Comp:  2          [OIII]5007_d      2.334      0.46     -59    30
# Comp:  2            [OI]6300_d      2.068      0.46     -59    30
# Comp:  2           [NII]6583_d      3.024      0.46     -59    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        74
#  comp.  1:       -61        44
#  comp.  2:       -61        25
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.357      0.38     -61    44
# Comp:  1                Halpha      12.24      0.38     -61    44
# Comp:  2             [SII]6716      4.807      0.36     -61    25
# Comp:  2             [SII]6731      3.661      0.36     -61    25
# Comp:  2              HeII4687     0.6942      0.36     -61    25
# Comp:  2               HeI5876     0.2843      0.36     -61    25
# Comp:  2          [OIII]5007_d      2.573      0.45     -61    25
# Comp:  2            [OI]6300_d      1.893      0.45     -61    25
# Comp:  2           [NII]6583_d      2.897      0.45     -61    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -64        49
#  comp.  2:       -56        36
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.653      0.39     -64    49
# Comp:  1                Halpha      12.50      0.39     -64    49
# Comp:  2             [SII]6716      5.061      0.37     -56    36
# Comp:  2             [SII]6731      3.595      0.37     -56    36
# Comp:  2              HeII4687     0.3573      0.37     -56    36
# Comp:  2               HeI5876     0.4312      0.37     -56    36
# Comp:  2          [OIII]5007_d      2.897      0.47     -56    36
# Comp:  2            [OI]6300_d      1.998      0.47     -56    36
# Comp:  2           [NII]6583_d      3.172      0.47     -56    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        59
#  comp.  1:       -59        32
#  comp.  2:       -60        30
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.311      0.37     -59    32
# Comp:  1                Halpha      11.93      0.37     -59    32
# Comp:  2             [SII]6716      5.008      0.36     -60    30
# Comp:  2             [SII]6731      3.329      0.36     -60    30
# Comp:  2              HeII4687     0.6374      0.36     -60    30
# Comp:  2               HeI5876     0.2864      0.36     -60    30
# Comp:  2          [OIII]5007_d      2.699      0.46     -60    30
# Comp:  2            [OI]6300_d      2.331      0.46     -60    30
# Comp:  2           [NII]6583_d      3.224      0.46     -60    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        87
#  comp.  1:       -60        42
#  comp.  2:       -60        27
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.577      0.38     -60    42
# Comp:  1                Halpha      12.17      0.38     -60    42
# Comp:  2             [SII]6716      4.538      0.36     -60    27
# Comp:  2             [SII]6731      3.256      0.36     -60    27
# Comp:  2              HeII4687     0.5171      0.36     -60    27
# Comp:  2               HeI5876    0.07594      0.36     -60    27
# Comp:  2          [OIII]5007_d      1.842      0.45     -60    27
# Comp:  2            [OI]6300_d      2.064      0.45     -60    27
# Comp:  2           [NII]6583_d      2.983      0.45     -60    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         8
#  comp.  1:       -56        24
#  comp.  2:       -59        25
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.433      0.36     -56    24
# Comp:  1                Halpha      11.13      0.36     -56    24
# Comp:  2             [SII]6716      4.677      0.36     -59    25
# Comp:  2             [SII]6731      3.667      0.36     -59    25
# Comp:  2              HeII4687     0.4899      0.36     -59    25
# Comp:  2               HeI5876      0.000      0.36     -59    25
# Comp:  2          [OIII]5007_d      2.438      0.45     -59    25
# Comp:  2            [OI]6300_d      1.975      0.45     -59    25
# Comp:  2           [NII]6583_d      3.021      0.45     -59    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        59
#  comp.  1:       -60        36
#  comp.  2:       -58        30
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.578      0.37     -60    36
# Comp:  1                Halpha      12.05      0.37     -60    36
# Comp:  2             [SII]6716      4.973      0.36     -58    30
# Comp:  2             [SII]6731      3.251      0.36     -58    30
# Comp:  2              HeII4687     0.3860      0.36     -58    30
# Comp:  2               HeI5876     0.1349      0.36     -58    30
# Comp:  2          [OIII]5007_d      2.729      0.46     -58    30
# Comp:  2            [OI]6300_d      2.250      0.46     -58    30
# Comp:  2           [NII]6583_d      3.219      0.46     -58    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        95
#  comp.  1:       -67        49
#  comp.  2:       -58        22
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.408      0.39     -67    49
# Comp:  1                Halpha      12.58      0.39     -67    49
# Comp:  2             [SII]6716      4.579      0.36     -58    22
# Comp:  2             [SII]6731      3.546      0.36     -58    22
# Comp:  2              HeII4687     0.4236      0.36     -58    22
# Comp:  2               HeI5876      0.000      0.36     -58    22
# Comp:  2          [OIII]5007_d      1.755      0.45     -58    22
# Comp:  2            [OI]6300_d      1.934      0.45     -58    22
# Comp:  2           [NII]6583_d      2.800      0.45     -58    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       117
#  comp.  1:       -65        49
#  comp.  2:       -57        31
# chi2/DOF: 1.289; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.618      0.39     -65    49
# Comp:  1                Halpha      12.44      0.39     -65    49
# Comp:  2             [SII]6716      4.839      0.36     -57    31
# Comp:  2             [SII]6731      3.319      0.36     -57    31
# Comp:  2              HeII4687     0.4697      0.36     -57    31
# Comp:  2               HeI5876      0.000      0.36     -57    31
# Comp:  2          [OIII]5007_d      2.681      0.46     -57    31
# Comp:  2            [OI]6300_d      1.783      0.46     -57    31
# Comp:  2           [NII]6583_d      2.933      0.46     -57    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         7
#  comp.  1:       -60        36
#  comp.  2:       -61        39
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.161      0.37     -60    36
# Comp:  1                Halpha      11.95      0.37     -60    36
# Comp:  2             [SII]6716      5.174      0.37     -61    39
# Comp:  2             [SII]6731      3.827      0.37     -61    39
# Comp:  2              HeII4687     0.4436      0.37     -61    39
# Comp:  2               HeI5876      0.000      0.37     -61    39
# Comp:  2          [OIII]5007_d      2.917      0.47     -61    39
# Comp:  2            [OI]6300_d      1.915      0.47     -61    39
# Comp:  2           [NII]6583_d      3.214      0.47     -61    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        77
#  comp.  1:       -66        47
#  comp.  2:       -56        33
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.507      0.38     -66    47
# Comp:  1                Halpha      12.88      0.38     -66    47
# Comp:  2             [SII]6716      4.894      0.37     -56    33
# Comp:  2             [SII]6731      3.832      0.37     -56    33
# Comp:  2              HeII4687     0.6619      0.37     -56    33
# Comp:  2               HeI5876      0.000      0.37     -56    33
# Comp:  2          [OIII]5007_d      2.814      0.46     -56    33
# Comp:  2            [OI]6300_d      2.145      0.46     -56    33
# Comp:  2           [NII]6583_d      3.096      0.46     -56    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6        78
#  comp.  1:       -61        38
#  comp.  2:       -56        20
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.578      0.37     -61    38
# Comp:  1                Halpha      11.46      0.37     -61    38
# Comp:  2             [SII]6716      4.637      0.35     -56    20
# Comp:  2             [SII]6731      3.429      0.35     -56    20
# Comp:  2              HeII4687     0.4130      0.35     -56    20
# Comp:  2               HeI5876      0.000      0.35     -56    20
# Comp:  2          [OIII]5007_d      2.626      0.45     -56    20
# Comp:  2            [OI]6300_d      1.845      0.45     -56    20
# Comp:  2           [NII]6583_d      2.724      0.45     -56    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        14
#  comp.  1:       -59        33
#  comp.  2:       -58        25
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.023      0.37     -59    33
# Comp:  1                Halpha      12.18      0.37     -59    33
# Comp:  2             [SII]6716      4.757      0.36     -58    25
# Comp:  2             [SII]6731      3.221      0.36     -58    25
# Comp:  2              HeII4687     0.6151      0.36     -58    25
# Comp:  2               HeI5876      0.000      0.36     -58    25
# Comp:  2          [OIII]5007_d      2.336      0.45     -58    25
# Comp:  2            [OI]6300_d      1.860      0.45     -58    25
# Comp:  2           [NII]6583_d      3.018      0.45     -58    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        21
#  comp.  1:       -65        45
#  comp.  2:       -59        21
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.607      0.38     -65    45
# Comp:  1                Halpha      12.49      0.38     -65    45
# Comp:  2             [SII]6716      4.750      0.36     -59    21
# Comp:  2             [SII]6731      3.475      0.36     -59    21
# Comp:  2              HeII4687     0.4005      0.36     -59    21
# Comp:  2               HeI5876     0.3130      0.36     -59    21
# Comp:  2          [OIII]5007_d      2.628      0.45     -59    21
# Comp:  2            [OI]6300_d      2.041      0.45     -59    21
# Comp:  2           [NII]6583_d      2.837      0.45     -59    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        48
#  comp.  1:       -59        34
#  comp.  2:       -56        25
# chi2/DOF: 1.288; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.934      0.37     -59    34
# Comp:  1                Halpha      12.20      0.37     -59    34
# Comp:  2             [SII]6716      4.762      0.36     -56    25
# Comp:  2             [SII]6731      3.196      0.36     -56    25
# Comp:  2              HeII4687     0.6503      0.36     -56    25
# Comp:  2               HeI5876      0.000      0.36     -56    25
# Comp:  2          [OIII]5007_d      1.981      0.45     -56    25
# Comp:  2            [OI]6300_d      2.319      0.45     -56    25
# Comp:  2           [NII]6583_d      2.885      0.45     -56    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        88
#  comp.  1:       -67        44
#  comp.  2:       -61        28
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.237      0.38     -67    44
# Comp:  1                Halpha      12.32      0.38     -67    44
# Comp:  2             [SII]6716      4.756      0.36     -61    28
# Comp:  2             [SII]6731      3.715      0.36     -61    28
# Comp:  2              HeII4687     0.6996      0.36     -61    28
# Comp:  2               HeI5876      0.000      0.36     -61    28
# Comp:  2          [OIII]5007_d      2.466      0.46     -61    28
# Comp:  2            [OI]6300_d      2.023      0.46     -61    28
# Comp:  2           [NII]6583_d      2.937      0.46     -61    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        74
#  comp.  1:       -61        35
#  comp.  2:       -61        26
# chi2/DOF: 1.282; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.706      0.37     -61    35
# Comp:  1                Halpha      11.88      0.37     -61    35
# Comp:  2             [SII]6716      4.972      0.36     -61    26
# Comp:  2             [SII]6731      3.335      0.36     -61    26
# Comp:  2              HeII4687     0.4700      0.36     -61    26
# Comp:  2               HeI5876     0.4096      0.36     -61    26
# Comp:  2          [OIII]5007_d      1.864      0.45     -61    26
# Comp:  2            [OI]6300_d      1.707      0.45     -61    26
# Comp:  2           [NII]6583_d      3.181      0.45     -61    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -55        27
#  comp.  2:       -59        17
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.023      0.36     -55    27
# Comp:  1                Halpha      11.70      0.36     -55    27
# Comp:  2             [SII]6716      4.847      0.35     -59    17
# Comp:  2             [SII]6731      3.554      0.35     -59    17
# Comp:  2              HeII4687     0.2345      0.35     -59    17
# Comp:  2               HeI5876     0.1401      0.35     -59    17
# Comp:  2          [OIII]5007_d      2.078      0.44     -59    17
# Comp:  2            [OI]6300_d      1.622      0.44     -59    17
# Comp:  2           [NII]6583_d      2.836      0.44     -59    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        67
#  comp.  1:       -65        45
#  comp.  2:       -61        32
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.529      0.38     -65    45
# Comp:  1                Halpha      12.79      0.38     -65    45
# Comp:  2             [SII]6716      4.654      0.36     -61    32
# Comp:  2             [SII]6731      3.533      0.36     -61    32
# Comp:  2              HeII4687     0.1561      0.36     -61    32
# Comp:  2               HeI5876     0.4002      0.36     -61    32
# Comp:  2          [OIII]5007_d      2.651      0.46     -61    32
# Comp:  2            [OI]6300_d      1.650      0.46     -61    32
# Comp:  2           [NII]6583_d      2.728      0.46     -61    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -55        27
#  comp.  2:       -60        39
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.243      0.36     -55    27
# Comp:  1                Halpha      11.35      0.36     -55    27
# Comp:  2             [SII]6716      4.986      0.37     -60    39
# Comp:  2             [SII]6731      3.554      0.37     -60    39
# Comp:  2              HeII4687     0.1547      0.37     -60    39
# Comp:  2               HeI5876      0.000      0.37     -60    39
# Comp:  2          [OIII]5007_d      2.683      0.47     -60    39
# Comp:  2            [OI]6300_d      2.474      0.47     -60    39
# Comp:  2           [NII]6583_d      2.982      0.47     -60    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:       -57        32
#  comp.  2:       -60        36
# chi2/DOF: 1.288; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.372      0.37     -57    32
# Comp:  1                Halpha      11.67      0.37     -57    32
# Comp:  2             [SII]6716      5.104      0.37     -60    36
# Comp:  2             [SII]6731      3.274      0.37     -60    36
# Comp:  2              HeII4687     0.6494      0.37     -60    36
# Comp:  2               HeI5876    0.09825      0.37     -60    36
# Comp:  2          [OIII]5007_d      2.777      0.47     -60    36
# Comp:  2            [OI]6300_d      2.265      0.47     -60    36
# Comp:  2           [NII]6583_d      2.927      0.47     -60    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        49
#  comp.  1:       -65        46
#  comp.  2:       -61        33
# chi2/DOF: 1.287; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.559      0.38     -65    46
# Comp:  1                Halpha      12.94      0.38     -65    46
# Comp:  2             [SII]6716      5.115      0.37     -61    33
# Comp:  2             [SII]6731      3.783      0.37     -61    33
# Comp:  2              HeII4687     0.1919      0.37     -61    33
# Comp:  2               HeI5876     0.3043      0.37     -61    33
# Comp:  2          [OIII]5007_d      2.478      0.46     -61    33
# Comp:  2            [OI]6300_d      1.922      0.46     -61    33
# Comp:  2           [NII]6583_d      2.810      0.46     -61    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        80
#  comp.  1:       -64        49
#  comp.  2:       -62        31
# chi2/DOF: 1.287; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.763      0.39     -64    49
# Comp:  1                Halpha      13.65      0.39     -64    49
# Comp:  2             [SII]6716      4.667      0.36     -62    31
# Comp:  2             [SII]6731      3.733      0.36     -62    31
# Comp:  2              HeII4687    0.08271      0.36     -62    31
# Comp:  2               HeI5876    0.07600      0.36     -62    31
# Comp:  2          [OIII]5007_d      1.906      0.46     -62    31
# Comp:  2            [OI]6300_d      2.100      0.46     -62    31
# Comp:  2           [NII]6583_d      3.022      0.46     -62    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       -63        45
#  comp.  2:       -60        34
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.495      0.38     -63    45
# Comp:  1                Halpha      12.60      0.38     -63    45
# Comp:  2             [SII]6716      4.849      0.37     -60    34
# Comp:  2             [SII]6731      3.402      0.37     -60    34
# Comp:  2              HeII4687     0.3155      0.37     -60    34
# Comp:  2               HeI5876      0.000      0.37     -60    34
# Comp:  2          [OIII]5007_d      2.574      0.46     -60    34
# Comp:  2            [OI]6300_d      1.972      0.46     -60    34
# Comp:  2           [NII]6583_d      2.739      0.46     -60    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        50
#  comp.  1:       -62        43
#  comp.  2:       -61        33
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.657      0.38     -62    43
# Comp:  1                Halpha      11.97      0.38     -62    43
# Comp:  2             [SII]6716      4.665      0.37     -61    33
# Comp:  2             [SII]6731      3.725      0.37     -61    33
# Comp:  2              HeII4687    0.09007      0.37     -61    33
# Comp:  2               HeI5876      0.000      0.37     -61    33
# Comp:  2          [OIII]5007_d      2.595      0.46     -61    33
# Comp:  2            [OI]6300_d      1.667      0.46     -61    33
# Comp:  2           [NII]6583_d      3.098      0.46     -61    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        93
#  comp.  1:       -59        45
#  comp.  2:       -55        11
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.351      0.38     -59    45
# Comp:  1                Halpha      12.68      0.38     -59    45
# Comp:  2             [SII]6716      4.389      0.35     -55    11
# Comp:  2             [SII]6731      3.295      0.35     -55    11
# Comp:  2              HeII4687     0.3407      0.35     -55    11
# Comp:  2               HeI5876      0.000      0.35     -55    11
# Comp:  2          [OIII]5007_d      2.346      0.44     -55    11
# Comp:  2            [OI]6300_d      1.664      0.44     -55    11
# Comp:  2           [NII]6583_d      2.864      0.44     -55    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -62        46
#  comp.  2:       -54        16
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.181      0.38     -62    46
# Comp:  1                Halpha      12.75      0.38     -62    46
# Comp:  2             [SII]6716      4.579      0.35     -54    16
# Comp:  2             [SII]6731      3.391      0.35     -54    16
# Comp:  2              HeII4687     0.6041      0.35     -54    16
# Comp:  2               HeI5876     0.2192      0.35     -54    16
# Comp:  2          [OIII]5007_d      2.623      0.44     -54    16
# Comp:  2            [OI]6300_d      2.023      0.44     -54    16
# Comp:  2           [NII]6583_d      2.565      0.44     -54    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:       -57        35
#  comp.  2:       -60        30
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.094      0.37     -57    35
# Comp:  1                Halpha      12.40      0.37     -57    35
# Comp:  2             [SII]6716      4.707      0.36     -60    30
# Comp:  2             [SII]6731      3.394      0.36     -60    30
# Comp:  2              HeII4687     0.4435      0.36     -60    30
# Comp:  2               HeI5876     0.1990      0.36     -60    30
# Comp:  2          [OIII]5007_d      2.383      0.46     -60    30
# Comp:  2            [OI]6300_d      1.991      0.46     -60    30
# Comp:  2           [NII]6583_d      3.052      0.46     -60    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        14
#  comp.  1:       -54        29
#  comp.  2:       -57        23
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.669      0.36     -54    29
# Comp:  1                Halpha      11.61      0.36     -54    29
# Comp:  2             [SII]6716      4.728      0.36     -57    23
# Comp:  2             [SII]6731      3.215      0.36     -57    23
# Comp:  2              HeII4687     0.3075      0.36     -57    23
# Comp:  2               HeI5876     0.1907      0.36     -57    23
# Comp:  2          [OIII]5007_d      1.952      0.45     -57    23
# Comp:  2            [OI]6300_d      2.229      0.45     -57    23
# Comp:  2           [NII]6583_d      2.887      0.45     -57    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        46
#  comp.  1:       -57        24
#  comp.  2:       -60        18
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.473      0.36     -57    24
# Comp:  1                Halpha      11.47      0.36     -57    24
# Comp:  2             [SII]6716      4.659      0.35     -60    18
# Comp:  2             [SII]6731      3.568      0.35     -60    18
# Comp:  2              HeII4687     0.3610      0.35     -60    18
# Comp:  2               HeI5876      0.000      0.35     -60    18
# Comp:  2          [OIII]5007_d      1.913      0.45     -60    18
# Comp:  2            [OI]6300_d      1.902      0.45     -60    18
# Comp:  2           [NII]6583_d      2.856      0.45     -60    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        43
#  comp.  1:       -57        24
#  comp.  2:       -57        22
# chi2/DOF: 1.289; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.814      0.36     -57    24
# Comp:  1                Halpha      11.30      0.36     -57    24
# Comp:  2             [SII]6716      4.752      0.36     -57    22
# Comp:  2             [SII]6731      3.613      0.36     -57    22
# Comp:  2              HeII4687    0.06472      0.36     -57    22
# Comp:  2               HeI5876     0.2827      0.36     -57    22
# Comp:  2          [OIII]5007_d      2.461      0.45     -57    22
# Comp:  2            [OI]6300_d      2.220      0.45     -57    22
# Comp:  2           [NII]6583_d      2.969      0.45     -57    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1         1
#  comp.  1:       -56        28
#  comp.  2:       -60         5
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.507      0.36     -56    28
# Comp:  1                Halpha      11.08      0.36     -56    28
# Comp:  2             [SII]6716      4.578      0.35     -60     5
# Comp:  2             [SII]6731      3.309      0.35     -60     5
# Comp:  2              HeII4687     0.3594      0.35     -60     5
# Comp:  2               HeI5876      0.000      0.35     -60     5
# Comp:  2          [OIII]5007_d      2.139      0.44     -60     5
# Comp:  2            [OI]6300_d      1.960      0.44     -60     5
# Comp:  2           [NII]6583_d      2.988      0.44     -60     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         8
#  comp.  1:       -56        29
#  comp.  2:       -57        34
# chi2/DOF: 1.292; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.924      0.36     -56    29
# Comp:  1                Halpha      11.30      0.36     -56    29
# Comp:  2             [SII]6716      4.915      0.37     -57    34
# Comp:  2             [SII]6731      3.574      0.37     -57    34
# Comp:  2              HeII4687     0.1356      0.37     -57    34
# Comp:  2               HeI5876      0.000      0.37     -57    34
# Comp:  2          [OIII]5007_d      2.589      0.46     -57    34
# Comp:  2            [OI]6300_d      2.059      0.46     -57    34
# Comp:  2           [NII]6583_d      2.808      0.46     -57    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        33
#  comp.  1:       -59        30
#  comp.  2:       -59        31
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.916      0.36     -59    30
# Comp:  1                Halpha      11.73      0.36     -59    30
# Comp:  2             [SII]6716      4.617      0.36     -59    31
# Comp:  2             [SII]6731      3.751      0.36     -59    31
# Comp:  2              HeII4687     0.4144      0.36     -59    31
# Comp:  2               HeI5876      0.000      0.36     -59    31
# Comp:  2          [OIII]5007_d      2.753      0.46     -59    31
# Comp:  2            [OI]6300_d      1.741      0.46     -59    31
# Comp:  2           [NII]6583_d      3.064      0.46     -59    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        54
#  comp.  1:       -58        37
#  comp.  2:       -60        43
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.448      0.37     -58    37
# Comp:  1                Halpha      12.33      0.37     -58    37
# Comp:  2             [SII]6716      5.277      0.38     -60    43
# Comp:  2             [SII]6731      3.882      0.38     -60    43
# Comp:  2              HeII4687     0.3730      0.38     -60    43
# Comp:  2               HeI5876      0.000      0.38     -60    43
# Comp:  2          [OIII]5007_d      2.818      0.48     -60    43
# Comp:  2            [OI]6300_d      2.018      0.48     -60    43
# Comp:  2           [NII]6583_d      3.118      0.48     -60    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        62
#  comp.  1:       -61        45
#  comp.  2:       -56         5
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.037      0.38     -61    45
# Comp:  1                Halpha      12.10      0.38     -61    45
# Comp:  2             [SII]6716      4.623      0.35     -56     5
# Comp:  2             [SII]6731      3.156      0.35     -56     5
# Comp:  2              HeII4687     0.4364      0.35     -56     5
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.279      0.37     -62    33
# Comp:  1                Halpha      12.13      0.37     -62    33
# Comp:  2             [SII]6716      4.435      0.35     -59     4
# Comp:  2             [SII]6731      3.370      0.35     -59     4
# Comp:  2              HeII4687     0.2689      0.35     -59     4
# Comp:  2               HeI5876      0.000      0.35     -59     4
# Comp:  2          [OIII]5007_d      2.074      0.44     -59     4
# Comp:  2            [OI]6300_d      1.803      0.44     -59     4
# Comp:  2           [NII]6583_d      3.149      0.44     -59     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        96
#  comp.  1:       -64        48
#  comp.  2:       -58        23
# chi2/DOF: 1.284; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.474      0.39     -64    48
# Comp:  1                Halpha      12.90      0.39     -64    48
# Comp:  2             [SII]6716      4.695      0.36     -58    23
# Comp:  2             [SII]6731      3.188      0.36     -58    23
# Comp:  2              HeII4687     0.4241      0.36     -58    23
# Comp:  2               HeI5876      0.000      0.36     -58    23
# Comp:  2          [OIII]5007_d      1.968      0.45     -58    23
# Comp:  2            [OI]6300_d      2.283      0.45     -58    23
# Comp:  2           [NII]6583_d      2.496      0.45     -58    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
#  comp.  1:       -53        26
#  comp.  2:       -55        21
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.435      0.36     -53    26
# Comp:  1                Halpha      11.51      0.36     -53    26
# Comp:  2             [SII]6716      4.600      0.35     -55    21
# Comp:  2             [SII]6731      3.137      0.35     -55    21
# Comp:  2              HeII4687     0.4050      0.35     -55    21
# Comp:  2               HeI5876     0.1095      0.35     -55    21
# Comp:  2          [OIII]5007_d      2.676      0.45     -55    21
# Comp:  2            [OI]6300_d      1.996      0.45     -55    21
# Comp:  2           [NII]6583_d      2.890      0.45     -55    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        10
#  comp.  1:       -57        35
#  comp.  2:       -60        31
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.691      0.37     -57    35
# Comp:  1                Halpha      12.05      0.37     -57    35
# Comp:  2             [SII]6716      4.829      0.36     -60    31
# Comp:  2             [SII]6731      3.360      0.36     -60    31
# Comp:  2              HeII4687     0.2057      0.36     -60    31
# Comp:  2               HeI5876     0.3278      0.36     -60    31
# Comp:  2          [OIII]5007_d      2.267      0.46     -60    31
# Comp:  2            [OI]6300_d      2.246      0.46     -60    31
# Comp:  2           [NII]6583_d      2.998      0.46     -60    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        65
#  comp.  1:       -63        47
#  comp.  2:       -63        35
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.377      0.38     -63    47
# Comp:  1                Halpha      12.33      0.38     -63    47
# Comp:  2             [SII]6716      5.036      0.37     -63    35
# Comp:  2             [SII]6731      3.463      0.37     -63    35
# Comp:  2              HeII4687     0.7522      0.37     -63    35
# Comp:  2               HeI5876      0.000      0.37     -63    35
# Comp:  2          [OIII]5007_d      2.184      0.47     -63    35
# Comp:  2            [OI]6300_d      1.835      0.47     -63    35
# Comp:  2           [NII]6583_d      3.040      0.47     -63    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -64        50
#  comp.  2:       -59        29
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.619      0.39     -64    50
# Comp:  1                Halpha      12.66      0.39     -64    50
# Comp:  2             [SII]6716      4.841      0.36     -59    29
# Comp:  2             [SII]6731      3.275      0.36     -59    29
# Comp:  2              HeII4687    0.08238      0.36     -59    29
# Comp:  2               HeI5876     0.2190      0.36     -59    29
# Comp:  2          [OIII]5007_d      1.764      0.46     -59    29
# Comp:  2            [OI]6300_d      1.772      0.46     -59    29
# Comp:  2           [NII]6583_d      2.828      0.46     -59    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        47
#  comp.  1:       -60        34
#  comp.  2:       -62        37
# chi2/DOF: 1.296; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.612      0.37     -60    34
# Comp:  1                Halpha      11.80      0.37     -60    34
# Comp:  2             [SII]6716      4.894      0.37     -62    37
# Comp:  2             [SII]6731      3.545      0.37     -62    37
# Comp:  2              HeII4687     0.3513      0.37     -62    37
# Comp:  2               HeI5876      0.000      0.37     -62    37
# Comp:  2          [OIII]5007_d      2.425      0.47     -62    37
# Comp:  2            [OI]6300_d      2.334      0.47     -62    37
# Comp:  2           [NII]6583_d      2.959      0.47     -62    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        38
#  comp.  1:       -59        42
#  comp.  2:       -61        22
# chi2/DOF: 1.291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.241      0.38     -59    42
# Comp:  1                Halpha      12.15      0.38     -59    42
# Comp:  2             [SII]6716      4.780      0.36     -61    22
# Comp:  2             [SII]6731      3.174      0.36     -61    22
# Comp:  2              HeII4687     0.7185      0.36     -61    22
# Comp:  2               HeI5876      0.000      0.36     -61    22
# Comp:  2          [OIII]5007_d      1.982      0.45     -61    22
# Comp:  2            [OI]6300_d      1.785      0.45     -61    22
# Comp:  2           [NII]6583_d      3.163      0.45     -61    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        82
#  comp.  1:       -66        44
#  comp.  2:       -60        16
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.582      0.38     -66    44
# Comp:  1                Halpha      12.21      0.38     -66    44
# Comp:  2             [SII]6716      4.644      0.35     -60    16
# Comp:  2             [SII]6731      3.161      0.35     -60    16
# Comp:  2              HeII4687     0.1245      0.35     -60    16
# Comp:  2               HeI5876      0.000      0.35     -60    16
# Comp:  2          [OIII]5007_d      1.878      0.44     -60    16
# Comp:  2            [OI]6300_d      1.863      0.44     -60    16
# Comp:  2           [NII]6583_d      2.638      0.44     -60    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        60
#  comp.  1:       -65        45
#  comp.  2:       -58        17
# chi2/DOF: 1.293; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.576      0.38     -65    45
# Comp:  1                Halpha      12.56      0.38     -65    45
# Comp:  2             [SII]6716      4.589      0.35     -58    17
# Comp:  2             [SII]6731      3.127      0.35     -58    17
# Comp:  2              HeII4687     0.4414      0.35     -58    17
# Comp:  2               HeI5876      0.000      0.35     -58    17
# Comp:  2          [OIII]5007_d      2.336      0.45     -58    17
# Comp:  2            [OI]6300_d      1.859      0.45     -58    17
# Comp:  2           [NII]6583_d      2.928      0.45     -58    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        72
#  comp.  1:       -61        33
#  comp.  2:       -63        32
# chi2/DOF: 1.294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.644      0.37     -61    33
# Comp:  1                Halpha      11.84      0.37     -61    33
# Comp:  2             [SII]6716      4.958      0.36     -63    32
# Comp:  2             [SII]6731      3.811      0.36     -63    32
# Comp:  2              HeII4687     0.4770      0.36     -63    32
# Comp:  2               HeI5876     0.1311      0.36     -63    32
# Comp:  2          [OIII]5007_d      2.178      0.46     -63    32
# Comp:  2            [OI]6300_d      1.941      0.46     -63    32
# Comp:  2           [NII]6583_d      3.079      0.46     -63    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        51
#  comp.  1:       -60        43
#  comp.  2:       -62        27
# chi2/DOF: 1.296; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.839      0.38     -60    43
# Comp:  1                Halpha      12.31      0.38     -60    43
# Comp:  2             [SII]6716      4.794      0.36     -62    27
# Comp:  2             [SII]6731      3.651      0.36     -62    27
# Comp:  2              HeII4687     0.4496      0.36     -62    27
# Comp:  2               HeI5876      0.000      0.36     -62    27
# Comp:  2          [OIII]5007_d      1.898      0.45     -62    27
# Comp:  2            [OI]6300_d      1.740      0.45     -62    27
# Comp:  2           [NII]6583_d      2.876      0.45     -62    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        43
#  comp.  1:       -55        20
#  comp.  2:       -48        29
# chi2/DOF: 1.288; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.133      0.35     -55    20
# Comp:  1                Halpha      11.22      0.35     -55    20
# Comp:  2             [SII]6716      4.832      0.36     -48    29
# Comp:  2             [SII]6731      3.567      0.36     -48    29
# Comp:  2              HeII4687     0.2460      0.36     -48    29
# Comp:  2               HeI5876     0.3949      0.36     -48    29
# Comp:  2          [OIII]5007_d      2.451      0.46     -48    29
# Comp:  2            [OI]6300_d      1.948      0.46     -48    29
# Comp:  2           [NII]6583_d      2.933      0.46     -48    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        24
#  comp.  1:       -63        43
#  comp.  2:       -60        17
# chi2/DOF: 1.290; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.838      0.38     -63    43
# Comp:  1                Halpha      12.52      0.38     -63    43
# Comp:  2             [SII]6716      4.812      0.35     -60    17
# Comp:  2             [SII]6731      3.119      0.35     -60    17
# Comp:  2              HeII4687     0.4408      0.35     -60    17
# Comp:  2               HeI5876     0.1762      0.35     -60    17
# Comp:  2          [OIII]5007_d      2.106      0.44     -60    17
# Comp:  2            [OI]6300_d      1.736      0.44     -60    17
# Comp:  2           [NII]6583_d      2.954      0.44     -60    17
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.42362478, 0.7019421 , 0.26080492, 0.28850041, 0.17888922,
#        0.17287209, 0.33254642, 0.24332157, 0.24337253])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.60330603, 16.26114126,  6.67082869,  4.82718303,  0.36873819,
#         0.        ,  2.39704798,  2.57697848,  3.97376377])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_11_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_11", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_11_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_11_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_11_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.141285    0.016610
# 1        Halpha  0.637598    0.027523
# 2     [SII]6716  0.261563    0.010226
# 3     [SII]6731  0.189274    0.011312
# 4      HeII4687  0.014458    0.007014
# 5       HeI5876  0.000000    0.006778
# 6  [OIII]5007_d  0.093988    0.013039
# 7    [OI]6300_d  0.101043    0.009541
# 8   [NII]6583_d  0.155811    0.009543
#           Name      Flux  Error_flux
# 0        Hbeta  0.141285    0.016610
# 1       Halpha  0.637598    0.027523
# 2    [SII]6716  0.261563    0.010226
# 3    [SII]6731  0.189274    0.011312
# 4     HeII4687  0.014458    0.007014
# 5      HeI5876  0.000000    0.006778
# 6   [OIII]4959  0.023497    0.013039
# 7   [OIII]5007  0.070491    0.013039
# 8     [OI]6300  0.075782    0.009541
# 9     [OI]6364  0.025261    0.009541
# 10   [NII]6548  0.038953    0.009543
# 11   [NII]6583  0.116858    0.009543

# %%
np.median(flux_rf_rebin)
# Out:
# 0.039209946192279896
