# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_9.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_9']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.07842678 0.08221273 0.09230789 ... 0.05376043 0.05507987 0.04871995] [0.00701323 0.00701323 0.00701323 ... 0.00701323 0.00701323 0.00701323]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
# chi2/DOF: 0.01579; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
# chi2/DOF: 0.007744; DOF: 1914; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-52.42531671,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -38         6
#  comp.  2:      -136       159
# chi2/DOF: 1.381; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1708      0.20     -38     6
# Comp:  1                Halpha     0.5917      0.20     -38     6
# Comp:  2             [SII]6716     0.2153      0.33    -136   159
# Comp:  2             [SII]6731     0.7846      0.33    -136   159
# Comp:  2              HeII4687     0.5375      0.33    -136   159
# Comp:  2               HeI5876      0.000      0.33    -136   159
# Comp:  2          [OIII]5007_d     0.8003      0.42    -136   159
# Comp:  2            [OI]6300_d     0.6728      0.42    -136   159
# Comp:  2           [NII]6583_d     0.9959      0.42    -136   159
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise: 0.6956; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  2.307; gas flux:      1 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.3467; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.259; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.8629; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.9591; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  0.809; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.205; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -81       146
#  comp.  2:      -120       132
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.32     -81   146
# Comp:  1                Halpha     0.8663      0.32     -81   146
# Comp:  2             [SII]6716      0.000      0.31    -120   132
# Comp:  2             [SII]6731     0.5624      0.31    -120   132
# Comp:  2              HeII4687     0.5076      0.31    -120   132
# Comp:  2               HeI5876     0.1754      0.31    -120   132
# Comp:  2          [OIII]5007_d     0.5748      0.39    -120   132
# Comp:  2            [OI]6300_d     0.8298      0.39    -120   132
# Comp:  2           [NII]6583_d     0.8935      0.39    -120   132
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:        -1        11
#  comp.  2:      -183       166
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6319      0.21      -1    11
# Comp:  1                Halpha     0.6952      0.21      -1    11
# Comp:  2             [SII]6716     0.3197      0.34    -183   166
# Comp:  2             [SII]6731     0.6295      0.34    -183   166
# Comp:  2              HeII4687      1.127      0.34    -183   166
# Comp:  2               HeI5876     0.3008      0.34    -183   166
# Comp:  2          [OIII]5007_d      1.094      0.42    -183   166
# Comp:  2            [OI]6300_d    0.01750      0.42    -183   166
# Comp:  2           [NII]6583_d     0.9268      0.42    -183   166
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         4
#  comp.  1:       -20         1
#  comp.  2:      -119       128
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.04764      0.20     -20     1
# Comp:  1                Halpha     0.8482      0.20     -20     1
# Comp:  2             [SII]6716      0.000      0.30    -119   128
# Comp:  2             [SII]6731     0.8750      0.30    -119   128
# Comp:  2              HeII4687     0.4186      0.30    -119   128
# Comp:  2               HeI5876      0.000      0.30    -119   128
# Comp:  2          [OIII]5007_d     0.7132      0.38    -119   128
# Comp:  2            [OI]6300_d      1.051      0.38    -119   128
# Comp:  2           [NII]6583_d     0.9778      0.38    -119   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         3
#  comp.  1:       -44         1
#  comp.  2:       -95       136
# chi2/DOF: 1.362; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2984      0.20     -44     1
# Comp:  1                Halpha     0.7790      0.20     -44     1
# Comp:  2             [SII]6716     0.4866      0.31     -95   136
# Comp:  2             [SII]6731     0.8544      0.31     -95   136
# Comp:  2              HeII4687     0.3790      0.31     -95   136
# Comp:  2               HeI5876    0.09065      0.31     -95   136
# Comp:  2          [OIII]5007_d      1.238      0.39     -95   136
# Comp:  2            [OI]6300_d     0.6467      0.39     -95   136
# Comp:  2           [NII]6583_d     0.9249      0.39     -95   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -36         1
#  comp.  2:       -89       141
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.20     -36     1
# Comp:  1                Halpha     0.6044      0.20     -36     1
# Comp:  2             [SII]6716     0.3049      0.31     -89   141
# Comp:  2             [SII]6731     0.8843      0.31     -89   141
# Comp:  2              HeII4687      0.000      0.31     -89   141
# Comp:  2               HeI5876     0.2478      0.31     -89   141
# Comp:  2          [OIII]5007_d     0.9771      0.40     -89   141
# Comp:  2            [OI]6300_d      1.169      0.40     -89   141
# Comp:  2           [NII]6583_d     0.9461      0.40     -89   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       -35         1
#  comp.  2:      -374       244
# chi2/DOF: 1.368; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3841      0.20     -35     1
# Comp:  1                Halpha     0.4872      0.20     -35     1
# Comp:  2             [SII]6716     0.5394      0.41    -374   244
# Comp:  2             [SII]6731     0.7421      0.41    -374   244
# Comp:  2              HeII4687     0.4275      0.40    -374   244
# Comp:  2               HeI5876      0.000      0.40    -374   244
# Comp:  2          [OIII]5007_d      1.541      0.50    -374   244
# Comp:  2            [OI]6300_d      2.830      0.50    -374   244
# Comp:  2           [NII]6583_d     0.3793      0.50    -374   244
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        25
#  comp.  1:       -37         1
#  comp.  2:      -141       157
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.03632      0.20     -37     1
# Comp:  1                Halpha     0.4140      0.20     -37     1
# Comp:  2             [SII]6716     0.3992      0.33    -141   157
# Comp:  2             [SII]6731     0.7197      0.33    -141   157
# Comp:  2              HeII4687     0.4692      0.33    -141   157
# Comp:  2               HeI5876      0.000      0.33    -141   157
# Comp:  2          [OIII]5007_d     0.7336      0.41    -141   157
# Comp:  2            [OI]6300_d     0.6179      0.41    -141   157
# Comp:  2           [NII]6583_d     0.6390      0.41    -141   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        22
#  comp.  1:       -51        62
#  comp.  2:      -547         1
# chi2/DOF: 1.328; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 18; Func calls: 133; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7982      0.24     -51    62
# Comp:  1                Halpha     0.6893      0.24     -51    62
# Comp:  2             [SII]6716    0.04752      0.20    -547     1
# Comp:  2             [SII]6731      0.000      0.20    -547     1
# Comp:  2              HeII4687    0.06367      0.20    -547     1
# Comp:  2               HeI5876      0.000      0.20    -547     1
# Comp:  2          [OIII]5007_d      0.000      0.26    -547     1
# Comp:  2            [OI]6300_d      2.751      0.26    -547     1
# Comp:  2           [NII]6583_d     0.1244      0.26    -547     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -27         1
#  comp.  2:       -98       122
# chi2/DOF: 1.374; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.20     -27     1
# Comp:  1                Halpha     0.4904      0.20     -27     1
# Comp:  2             [SII]6716      0.000      0.30     -98   122
# Comp:  2             [SII]6731     0.9099      0.30     -98   122
# Comp:  2              HeII4687     0.3421      0.30     -98   122
# Comp:  2               HeI5876     0.3458      0.30     -98   122
# Comp:  2          [OIII]5007_d     0.7699      0.37     -98   122
# Comp:  2            [OI]6300_d    0.08596      0.37     -98   122
# Comp:  2           [NII]6583_d      1.019      0.37     -98   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:       -31        11
#  comp.  2:      -129       122
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2543      0.21     -31    11
# Comp:  1                Halpha     0.5513      0.21     -31    11
# Comp:  2             [SII]6716    0.04391      0.30    -129   122
# Comp:  2             [SII]6731     0.6517      0.30    -129   122
# Comp:  2              HeII4687     0.3309      0.30    -129   122
# Comp:  2               HeI5876     0.2834      0.30    -129   122
# Comp:  2          [OIII]5007_d     0.9299      0.37    -129   122
# Comp:  2            [OI]6300_d     0.8545      0.37    -129   122
# Comp:  2           [NII]6583_d     0.8884      0.37    -129   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        16
#  comp.  1:       -40         1
#  comp.  2:      -136       157
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5076      0.20     -40     1
# Comp:  1                Halpha     0.6720      0.20     -40     1
# Comp:  2             [SII]6716     0.7353      0.33    -136   157
# Comp:  2             [SII]6731     0.7427      0.33    -136   157
# Comp:  2              HeII4687     0.1882      0.33    -136   157
# Comp:  2               HeI5876    0.09233      0.33    -136   157
# Comp:  2          [OIII]5007_d     0.4528      0.41    -136   157
# Comp:  2            [OI]6300_d     0.9639      0.41    -136   157
# Comp:  2           [NII]6583_d     0.9949      0.41    -136   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        34
#  comp.  1:       -40        12
#  comp.  2:      -136       156
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5359      0.21     -40    12
# Comp:  1                Halpha     0.7099      0.21     -40    12
# Comp:  2             [SII]6716     0.4561      0.33    -136   156
# Comp:  2             [SII]6731     0.7117      0.33    -136   156
# Comp:  2              HeII4687      0.000      0.33    -136   156
# Comp:  2               HeI5876      0.000      0.33    -136   156
# Comp:  2          [OIII]5007_d     0.8999      0.41    -136   156
# Comp:  2            [OI]6300_d     0.2208      0.41    -136   156
# Comp:  2           [NII]6583_d     0.8695      0.41    -136   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        17
#  comp.  1:       -40        56
#  comp.  2:      -129       152
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.045      0.23     -40    56
# Comp:  1                Halpha     0.7545      0.23     -40    56
# Comp:  2             [SII]6716     0.4645      0.32    -129   152
# Comp:  2             [SII]6731     0.5892      0.32    -129   152
# Comp:  2              HeII4687     0.2849      0.32    -129   152
# Comp:  2               HeI5876      0.000      0.32    -129   152
# Comp:  2          [OIII]5007_d     0.9269      0.41    -129   152
# Comp:  2            [OI]6300_d     0.5821      0.41    -129   152
# Comp:  2           [NII]6583_d     0.9240      0.41    -129   152
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -28         1
#  comp.  2:      -203       295
# chi2/DOF: 1.363; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.20     -28     1
# Comp:  1                Halpha     0.6605      0.20     -28     1
# Comp:  2             [SII]6716     0.2525      0.46    -203   295
# Comp:  2             [SII]6731     0.9699      0.46    -203   295
# Comp:  2              HeII4687      1.107      0.44    -203   295
# Comp:  2               HeI5876      0.000      0.44    -203   295
# Comp:  2          [OIII]5007_d     0.7950      0.55    -203   295
# Comp:  2            [OI]6300_d      1.600      0.55    -203   295
# Comp:  2           [NII]6583_d      1.430      0.55    -203   295
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -33         1
#  comp.  2:      -140       183
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1044      0.20     -33     1
# Comp:  1                Halpha     0.6356      0.20     -33     1
# Comp:  2             [SII]6716     0.4079      0.35    -140   183
# Comp:  2             [SII]6731     0.8318      0.35    -140   183
# Comp:  2              HeII4687      1.023      0.35    -140   183
# Comp:  2               HeI5876      0.000      0.35    -140   183
# Comp:  2          [OIII]5007_d     0.9335      0.44    -140   183
# Comp:  2            [OI]6300_d     0.1781      0.44    -140   183
# Comp:  2           [NII]6583_d      1.226      0.44    -140   183
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -29         1
#  comp.  2:      -127       170
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.20     -29     1
# Comp:  1                Halpha     0.5628      0.20     -29     1
# Comp:  2             [SII]6716      0.000      0.34    -127   170
# Comp:  2             [SII]6731      1.053      0.34    -127   170
# Comp:  2              HeII4687     0.1986      0.34    -127   170
# Comp:  2               HeI5876    0.09505      0.34    -127   170
# Comp:  2          [OIII]5007_d     0.7697      0.43    -127   170
# Comp:  2            [OI]6300_d     0.9165      0.43    -127   170
# Comp:  2           [NII]6583_d     0.9625      0.43    -127   170
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -32         1
#  comp.  2:      -178       158
# chi2/DOF: 1.374; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5928      0.20     -32     1
# Comp:  1                Halpha     0.5855      0.20     -32     1
# Comp:  2             [SII]6716     0.3830      0.33    -178   158
# Comp:  2             [SII]6731      1.108      0.33    -178   158
# Comp:  2              HeII4687      0.000      0.33    -178   158
# Comp:  2               HeI5876     0.2293      0.33    -178   158
# Comp:  2          [OIII]5007_d     0.7425      0.42    -178   158
# Comp:  2            [OI]6300_d     0.5404      0.42    -178   158
# Comp:  2           [NII]6583_d      1.244      0.42    -178   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:      -101        30
#  comp.  2:      -106       151
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4678      0.21    -101    30
# Comp:  1                Halpha     0.5014      0.21    -101    30
# Comp:  2             [SII]6716     0.5631      0.32    -106   151
# Comp:  2             [SII]6731     0.9547      0.32    -106   151
# Comp:  2              HeII4687     0.1614      0.32    -106   151
# Comp:  2               HeI5876      0.000      0.32    -106   151
# Comp:  2          [OIII]5007_d     0.9189      0.41    -106   151
# Comp:  2            [OI]6300_d      1.045      0.41    -106   151
# Comp:  2           [NII]6583_d      1.119      0.41    -106   151
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:        21         1
#  comp.  2:      -551         1
# chi2/DOF: 1.343; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4582      0.20      21     1
# Comp:  1                Halpha     0.3926      0.20      21     1
# Comp:  2             [SII]6716    0.03394      0.20    -551     1
# Comp:  2             [SII]6731    0.02517      0.20    -551     1
# Comp:  2              HeII4687     0.1764      0.20    -551     1
# Comp:  2               HeI5876      0.000      0.20    -551     1
# Comp:  2          [OIII]5007_d      0.000      0.26    -551     1
# Comp:  2            [OI]6300_d      2.406      0.26    -551     1
# Comp:  2           [NII]6583_d      0.000      0.26    -551     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -63         1
#  comp.  2:      -174       234
# chi2/DOF: 1.372; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7548      0.20     -63     1
# Comp:  1                Halpha     0.7326      0.20     -63     1
# Comp:  2             [SII]6716     0.2897      0.40    -174   234
# Comp:  2             [SII]6731      1.029      0.40    -174   234
# Comp:  2              HeII4687     0.7309      0.39    -174   234
# Comp:  2               HeI5876      0.000      0.39    -174   234
# Comp:  2          [OIII]5007_d      1.295      0.49    -174   234
# Comp:  2            [OI]6300_d    0.01724      0.49    -174   234
# Comp:  2           [NII]6583_d     0.9762      0.49    -174   234
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -53         1
#  comp.  2:      -198       219
# chi2/DOF: 1.364; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6792      0.20     -53     1
# Comp:  1                Halpha     0.6848      0.20     -53     1
# Comp:  2             [SII]6716     0.4267      0.38    -198   219
# Comp:  2             [SII]6731     0.4770      0.38    -198   219
# Comp:  2              HeII4687     0.7984      0.38    -198   219
# Comp:  2               HeI5876     0.1209      0.38    -198   219
# Comp:  2          [OIII]5007_d      1.101      0.48    -198   219
# Comp:  2            [OI]6300_d     0.8695      0.48    -198   219
# Comp:  2           [NII]6583_d      1.251      0.48    -198   219
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        19
#  comp.  1:       -37         1
#  comp.  2:      -144       165
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2023      0.20     -37     1
# Comp:  1                Halpha     0.7547      0.20     -37     1
# Comp:  2             [SII]6716    0.07503      0.34    -144   165
# Comp:  2             [SII]6731     0.7186      0.34    -144   165
# Comp:  2              HeII4687     0.9053      0.34    -144   165
# Comp:  2               HeI5876      0.000      0.34    -144   165
# Comp:  2          [OIII]5007_d     0.6835      0.42    -144   165
# Comp:  2            [OI]6300_d      1.434      0.42    -144   165
# Comp:  2           [NII]6583_d      1.127      0.42    -144   165
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         9
#  comp.  1:       -29         1
#  comp.  2:      -114       154
# chi2/DOF: 1.362; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2991      0.20     -29     1
# Comp:  1                Halpha     0.5699      0.20     -29     1
# Comp:  2             [SII]6716     0.3466      0.32    -114   154
# Comp:  2             [SII]6731     0.7595      0.32    -114   154
# Comp:  2              HeII4687     0.3053      0.32    -114   154
# Comp:  2               HeI5876     0.3380      0.32    -114   154
# Comp:  2          [OIII]5007_d     0.8023      0.41    -114   154
# Comp:  2            [OI]6300_d     0.2658      0.41    -114   154
# Comp:  2           [NII]6583_d     0.6213      0.41    -114   154
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -65         1
#  comp.  2:      -549        65
# chi2/DOF: 1.330; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4672      0.20     -65     1
# Comp:  1                Halpha     0.8726      0.20     -65     1
# Comp:  2             [SII]6716      0.000      0.24    -549    65
# Comp:  2             [SII]6731      0.000      0.24    -549    65
# Comp:  2              HeII4687      0.000      0.24    -549    65
# Comp:  2               HeI5876    0.06490      0.24    -549    65
# Comp:  2          [OIII]5007_d     0.1449      0.31    -549    65
# Comp:  2            [OI]6300_d      3.396      0.31    -549    65
# Comp:  2           [NII]6583_d     0.4671      0.31    -549    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -38         1
#  comp.  2:      -123       144
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1900      0.20     -38     1
# Comp:  1                Halpha     0.5921      0.20     -38     1
# Comp:  2             [SII]6716     0.4874      0.32    -123   144
# Comp:  2             [SII]6731     0.7252      0.32    -123   144
# Comp:  2              HeII4687     0.5928      0.32    -123   144
# Comp:  2               HeI5876   0.003184      0.32    -123   144
# Comp:  2          [OIII]5007_d     0.8717      0.40    -123   144
# Comp:  2            [OI]6300_d     0.9238      0.40    -123   144
# Comp:  2           [NII]6583_d      1.065      0.40    -123   144
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -28        71
#  comp.  2:      -144        78
# chi2/DOF: 1.374; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2695      0.25     -28    71
# Comp:  1                Halpha     0.9277      0.25     -28    71
# Comp:  2             [SII]6716    0.01017      0.25    -144    78
# Comp:  2             [SII]6731     0.4953      0.25    -144    78
# Comp:  2              HeII4687     0.2498      0.25    -144    78
# Comp:  2               HeI5876      0.000      0.25    -144    78
# Comp:  2          [OIII]5007_d     0.6587      0.32    -144    78
# Comp:  2            [OI]6300_d     0.9982      0.32    -144    78
# Comp:  2           [NII]6583_d     0.5718      0.32    -144    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -48        32
#  comp.  2:      -205        95
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.22     -48    32
# Comp:  1                Halpha     0.5806      0.22     -48    32
# Comp:  2             [SII]6716    0.01833      0.27    -205    95
# Comp:  2             [SII]6731     0.7482      0.27    -205    95
# Comp:  2              HeII4687     0.2623      0.27    -205    95
# Comp:  2               HeI5876      0.000      0.27    -205    95
# Comp:  2          [OIII]5007_d     0.7893      0.34    -205    95
# Comp:  2            [OI]6300_d     0.7768      0.34    -205    95
# Comp:  2           [NII]6583_d     0.9607      0.34    -205    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -45        36
#  comp.  2:      -131       149
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9866      0.22     -45    36
# Comp:  1                Halpha     0.7389      0.22     -45    36
# Comp:  2             [SII]6716      0.000      0.32    -131   149
# Comp:  2             [SII]6731     0.8727      0.32    -131   149
# Comp:  2              HeII4687     0.4745      0.32    -131   149
# Comp:  2               HeI5876     0.2564      0.32    -131   149
# Comp:  2          [OIII]5007_d     0.5248      0.40    -131   149
# Comp:  2            [OI]6300_d     0.5258      0.40    -131   149
# Comp:  2           [NII]6583_d      1.091      0.40    -131   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        -9         1
#  comp.  2:      -547        82
# chi2/DOF: 1.331; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4291      0.20      -9     1
# Comp:  1                Halpha     0.5296      0.20      -9     1
# Comp:  2             [SII]6716      0.000      0.26    -547    82
# Comp:  2             [SII]6731     0.2576      0.26    -547    82
# Comp:  2              HeII4687      0.000      0.26    -547    82
# Comp:  2               HeI5876      0.000      0.26    -547    82
# Comp:  2          [OIII]5007_d     0.2005      0.33    -547    82
# Comp:  2            [OI]6300_d      3.501      0.33    -547    82
# Comp:  2           [NII]6583_d     0.2727      0.33    -547    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        45
#  comp.  1:       -16        21
#  comp.  2:      -572         1
# chi2/DOF: 1.347; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 21; Func calls: 154; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4025      0.21     -16    21
# Comp:  1                Halpha     0.9137      0.21     -16    21
# Comp:  2             [SII]6716      0.000      0.20    -572     1
# Comp:  2             [SII]6731    0.06610      0.20    -572     1
# Comp:  2              HeII4687    0.06028      0.20    -572     1
# Comp:  2               HeI5876      0.000      0.20    -572     1
# Comp:  2          [OIII]5007_d     0.2935      0.26    -572     1
# Comp:  2            [OI]6300_d      2.200      0.26    -572     1
# Comp:  2           [NII]6583_d     0.1014      0.26    -572     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        24
#  comp.  1:       -38         1
#  comp.  2:      -137       160
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5294      0.20     -38     1
# Comp:  1                Halpha     0.5384      0.20     -38     1
# Comp:  2             [SII]6716     0.4158      0.33    -137   160
# Comp:  2             [SII]6731     0.9179      0.33    -137   160
# Comp:  2              HeII4687     0.6409      0.33    -137   160
# Comp:  2               HeI5876      0.000      0.33    -137   160
# Comp:  2          [OIII]5007_d     0.4802      0.42    -137   160
# Comp:  2            [OI]6300_d      1.014      0.42    -137   160
# Comp:  2           [NII]6583_d     0.8645      0.42    -137   160
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -78         9
#  comp.  2:      -127       131
# chi2/DOF: 1.376; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5955      0.21     -78     9
# Comp:  1                Halpha     0.6820      0.21     -78     9
# Comp:  2             [SII]6716     0.1952      0.30    -127   131
# Comp:  2             [SII]6731     0.8406      0.30    -127   131
# Comp:  2              HeII4687     0.7064      0.30    -127   131
# Comp:  2               HeI5876      0.000      0.30    -127   131
# Comp:  2          [OIII]5007_d     0.7431      0.38    -127   131
# Comp:  2            [OI]6300_d     0.4328      0.38    -127   131
# Comp:  2           [NII]6583_d     0.8006      0.38    -127   131
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        34
#  comp.  1:       -61         1
#  comp.  2:      -123       101
# chi2/DOF: 1.367; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4803      0.20     -61     1
# Comp:  1                Halpha     0.4866      0.20     -61     1
# Comp:  2             [SII]6716     0.3536      0.28    -123   101
# Comp:  2             [SII]6731     0.7277      0.28    -123   101
# Comp:  2              HeII4687     0.4511      0.28    -123   101
# Comp:  2               HeI5876      0.000      0.28    -123   101
# Comp:  2          [OIII]5007_d     0.6491      0.35    -123   101
# Comp:  2            [OI]6300_d     0.9202      0.35    -123   101
# Comp:  2           [NII]6583_d     0.7696      0.35    -123   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        19
#  comp.  1:       -55         1
#  comp.  2:      -131       118
# chi2/DOF: 1.372; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6215      0.20     -55     1
# Comp:  1                Halpha     0.7006      0.20     -55     1
# Comp:  2             [SII]6716     0.4868      0.29    -131   118
# Comp:  2             [SII]6731     0.7621      0.29    -131   118
# Comp:  2              HeII4687     0.4039      0.29    -131   118
# Comp:  2               HeI5876     0.1019      0.29    -131   118
# Comp:  2          [OIII]5007_d     0.9397      0.37    -131   118
# Comp:  2            [OI]6300_d     0.4267      0.37    -131   118
# Comp:  2           [NII]6583_d     0.8576      0.37    -131   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        21
#  comp.  1:       -38        13
#  comp.  2:      -140       161
# chi2/DOF: 1.377; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.04510      0.21     -38    13
# Comp:  1                Halpha     0.6460      0.21     -38    13
# Comp:  2             [SII]6716     0.2902      0.33    -140   161
# Comp:  2             [SII]6731     0.5161      0.33    -140   161
# Comp:  2              HeII4687     0.5472      0.33    -140   161
# Comp:  2               HeI5876      0.000      0.33    -140   161
# Comp:  2          [OIII]5007_d     0.8289      0.42    -140   161
# Comp:  2            [OI]6300_d     0.4258      0.42    -140   161
# Comp:  2           [NII]6583_d     0.8616      0.42    -140   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -28         1
#  comp.  2:      -104       156
# chi2/DOF: 1.375; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2997      0.20     -28     1
# Comp:  1                Halpha     0.7077      0.20     -28     1
# Comp:  2             [SII]6716     0.4096      0.33    -104   156
# Comp:  2             [SII]6731     0.8380      0.33    -104   156
# Comp:  2              HeII4687     0.7131      0.33    -104   156
# Comp:  2               HeI5876      0.000      0.33    -104   156
# Comp:  2          [OIII]5007_d     0.9765      0.41    -104   156
# Comp:  2            [OI]6300_d     0.9307      0.41    -104   156
# Comp:  2           [NII]6583_d     0.9793      0.41    -104   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        26         1
#  comp.  2:      -122       273
# chi2/DOF: 1.367; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6188      0.20      26     1
# Comp:  1                Halpha     0.4477      0.20      26     1
# Comp:  2             [SII]6716    0.03653      0.44    -122   273
# Comp:  2             [SII]6731      1.037      0.44    -122   273
# Comp:  2              HeII4687      1.147      0.42    -122   273
# Comp:  2               HeI5876      0.000      0.42    -122   273
# Comp:  2          [OIII]5007_d      1.105      0.53    -122   273
# Comp:  2            [OI]6300_d     0.6516      0.53    -122   273
# Comp:  2           [NII]6583_d      1.384      0.53    -122   273
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        37
#  comp.  1:       -42        53
#  comp.  2:       -86        81
# chi2/DOF: 1.366; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.05502      0.23     -42    53
# Comp:  1                Halpha     0.6807      0.23     -42    53
# Comp:  2             [SII]6716    0.05964      0.26     -86    81
# Comp:  2             [SII]6731     0.6616      0.26     -86    81
# Comp:  2              HeII4687     0.2540      0.26     -86    81
# Comp:  2               HeI5876     0.1864      0.26     -86    81
# Comp:  2          [OIII]5007_d     0.8315      0.32     -86    81
# Comp:  2            [OI]6300_d     0.7595      0.32     -86    81
# Comp:  2           [NII]6583_d     0.5642      0.32     -86    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        45
#  comp.  1:       -68        34
#  comp.  2:      -228       173
# chi2/DOF: 1.369; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.22     -68    34
# Comp:  1                Halpha     0.5959      0.22     -68    34
# Comp:  2             [SII]6716    0.05843      0.34    -228   173
# Comp:  2             [SII]6731     0.9335      0.34    -228   173
# Comp:  2              HeII4687     0.4934      0.34    -228   173
# Comp:  2               HeI5876      0.000      0.34    -228   173
# Comp:  2          [OIII]5007_d     0.4757      0.43    -228   173
# Comp:  2            [OI]6300_d      1.696      0.43    -228   173
# Comp:  2           [NII]6583_d      1.158      0.43    -228   173
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        17
#  comp.  1:       -39         6
#  comp.  2:      -136       158
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2378      0.20     -39     6
# Comp:  1                Halpha     0.4884      0.20     -39     6
# Comp:  2             [SII]6716     0.2972      0.33    -136   158
# Comp:  2             [SII]6731      1.143      0.33    -136   158
# Comp:  2              HeII4687     0.3564      0.33    -136   158
# Comp:  2               HeI5876     0.1258      0.33    -136   158
# Comp:  2          [OIII]5007_d     0.8734      0.42    -136   158
# Comp:  2            [OI]6300_d     0.6965      0.42    -136   158
# Comp:  2           [NII]6583_d     0.8654      0.42    -136   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        22
#  comp.  1:       -23         1
#  comp.  2:       -85       153
# chi2/DOF: 1.368; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1634      0.20     -23     1
# Comp:  1                Halpha     0.5496      0.20     -23     1
# Comp:  2             [SII]6716      0.000      0.32     -85   153
# Comp:  2             [SII]6731     0.9031      0.32     -85   153
# Comp:  2              HeII4687     0.2428      0.32     -85   153
# Comp:  2               HeI5876      0.000      0.32     -85   153
# Comp:  2          [OIII]5007_d     0.7847      0.41     -85   153
# Comp:  2            [OI]6300_d      0.000      0.41     -85   153
# Comp:  2           [NII]6583_d     0.8086      0.41     -85   153
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        16
#  comp.  1:       -85         1
#  comp.  2:      -156       186
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5637      0.20     -85     1
# Comp:  1                Halpha     0.3965      0.20     -85     1
# Comp:  2             [SII]6716     0.3382      0.35    -156   186
# Comp:  2             [SII]6731     0.9319      0.35    -156   186
# Comp:  2              HeII4687      1.231      0.35    -156   186
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3254      0.21     -38    16
# Comp:  1                Halpha     0.4708      0.21     -38    16
# Comp:  2             [SII]6716     0.3216      0.33    -135   157
# Comp:  2             [SII]6731     0.8298      0.33    -135   157
# Comp:  2              HeII4687     0.9116      0.33    -135   157
# Comp:  2               HeI5876      0.000      0.33    -135   157
# Comp:  2          [OIII]5007_d      1.008      0.41    -135   157
# Comp:  2            [OI]6300_d     0.6717      0.41    -135   157
# Comp:  2           [NII]6583_d     0.8395      0.41    -135   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -18         1
#  comp.  2:      -549         1
# chi2/DOF: 1.318; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1226      0.20     -18     1
# Comp:  1                Halpha     0.4926      0.20     -18     1
# Comp:  2             [SII]6716      0.000      0.20    -549     1
# Comp:  2             [SII]6731    0.08655      0.20    -549     1
# Comp:  2              HeII4687    0.05904      0.20    -549     1
# Comp:  2               HeI5876    0.05471      0.20    -549     1
# Comp:  2          [OIII]5007_d     0.1401      0.26    -549     1
# Comp:  2            [OI]6300_d      2.878      0.26    -549     1
# Comp:  2           [NII]6583_d      0.000      0.26    -549     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -56        49
#  comp.  2:      -202       207
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.030      0.23     -56    49
# Comp:  1                Halpha     0.8706      0.23     -56    49
# Comp:  2             [SII]6716     0.4884      0.37    -202   207
# Comp:  2             [SII]6731     0.8922      0.37    -202   207
# Comp:  2              HeII4687     0.8690      0.37    -202   207
# Comp:  2               HeI5876      0.000      0.37    -202   207
# Comp:  2          [OIII]5007_d     0.7600      0.47    -202   207
# Comp:  2            [OI]6300_d     0.7843      0.47    -202   207
# Comp:  2           [NII]6583_d      1.283      0.47    -202   207
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        23
#  comp.  1:       -37         3
#  comp.  2:      -136       162
# chi2/DOF: 1.375; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.02787      0.20     -37     3
# Comp:  1                Halpha     0.5916      0.20     -37     3
# Comp:  2             [SII]6716     0.5196      0.33    -136   162
# Comp:  2             [SII]6731     0.8188      0.33    -136   162
# Comp:  2              HeII4687     0.3303      0.33    -136   162
# Comp:  2               HeI5876     0.4261      0.33    -136   162
# Comp:  2          [OIII]5007_d     0.9703      0.42    -136   162
# Comp:  2            [OI]6300_d      0.000      0.42    -136   162
# Comp:  2           [NII]6583_d      1.124      0.42    -136   162
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        39
#  comp.  1:       -66         1
#  comp.  2:      -551        98
# chi2/DOF: 1.329; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 19; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4917      0.20     -66     1
# Comp:  1                Halpha     0.4191      0.20     -66     1
# Comp:  2             [SII]6716    0.09250      0.27    -551    98
# Comp:  2             [SII]6731      0.000      0.27    -551    98
# Comp:  2              HeII4687     0.3220      0.27    -551    98
# Comp:  2               HeI5876      0.000      0.27    -551    98
# Comp:  2          [OIII]5007_d     0.1096      0.34    -551    98
# Comp:  2            [OI]6300_d      3.706      0.34    -551    98
# Comp:  2           [NII]6583_d    0.07888      0.34    -551    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        25
#  comp.  1:       -37         1
#  comp.  2:      -132       156
# chi2/DOF: 1.368; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2473      0.20     -37     1
# Comp:  1                Halpha     0.5849      0.20     -37     1
# Comp:  2             [SII]6716    0.03398      0.33    -132   156
# Comp:  2             [SII]6731     0.5088      0.33    -132   156
# Comp:  2              HeII4687     0.5663      0.33    -132   156
# Comp:  2               HeI5876     0.3685      0.33    -132   156
# Comp:  2          [OIII]5007_d     0.4096      0.41    -132   156
# Comp:  2            [OI]6300_d     0.1829      0.41    -132   156
# Comp:  2           [NII]6583_d      1.323      0.41    -132   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -61        50
#  comp.  2:      -143       150
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8118      0.23     -61    50
# Comp:  1                Halpha     0.6086      0.23     -61    50
# Comp:  2             [SII]6716     0.3522      0.32    -143   150
# Comp:  2             [SII]6731     0.8499      0.32    -143   150
# Comp:  2              HeII4687     0.2034      0.32    -143   150
# Comp:  2               HeI5876     0.1524      0.32    -143   150
# Comp:  2          [OIII]5007_d     0.7141      0.41    -143   150
# Comp:  2            [OI]6300_d      1.071      0.41    -143   150
# Comp:  2           [NII]6583_d      1.116      0.41    -143   150
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -43        26
#  comp.  2:        -1       306
# chi2/DOF: 1.372; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.21     -43    26
# Comp:  1                Halpha     0.6040      0.21     -43    26
# Comp:  2             [SII]6716     0.5797      0.47      -1   306
# Comp:  2             [SII]6731     0.7100      0.47      -1   306
# Comp:  2              HeII4687      1.033      0.44      -1   306
# Comp:  2               HeI5876     0.4468      0.44      -1   306
# Comp:  2          [OIII]5007_d      1.739      0.56      -1   306
# Comp:  2            [OI]6300_d     0.9142      0.56      -1   306
# Comp:  2           [NII]6583_d      1.320      0.56      -1   306
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -14         1
#  comp.  2:      -193       143
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5548      0.20     -14     1
# Comp:  1                Halpha     0.6624      0.20     -14     1
# Comp:  2             [SII]6716     0.2712      0.31    -193   143
# Comp:  2             [SII]6731     0.5743      0.31    -193   143
# Comp:  2              HeII4687     0.6033      0.31    -193   143
# Comp:  2               HeI5876     0.4412      0.31    -193   143
# Comp:  2          [OIII]5007_d     0.7032      0.40    -193   143
# Comp:  2            [OI]6300_d     0.4072      0.40    -193   143
# Comp:  2           [NII]6583_d      1.261      0.40    -193   143
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        20
#  comp.  1:       -39        14
#  comp.  2:      -135       157
# chi2/DOF: 1.372; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3304      0.21     -39    14
# Comp:  1                Halpha     0.4882      0.21     -39    14
# Comp:  2             [SII]6716     0.4292      0.33    -135   157
# Comp:  2             [SII]6731     0.7267      0.33    -135   157
# Comp:  2              HeII4687     0.5047      0.33    -135   157
# Comp:  2               HeI5876   0.006655      0.33    -135   157
# Comp:  2          [OIII]5007_d     0.8477      0.41    -135   157
# Comp:  2            [OI]6300_d     0.6686      0.41    -135   157
# Comp:  2           [NII]6583_d      1.091      0.41    -135   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -31        27
#  comp.  2:      -541         1
# chi2/DOF: 1.339; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 21; Func calls: 149; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3873      0.21     -31    27
# Comp:  1                Halpha     0.4961      0.21     -31    27
# Comp:  2             [SII]6716      0.000      0.20    -541     1
# Comp:  2             [SII]6731    0.07276      0.20    -541     1
# Comp:  2              HeII4687      0.000      0.20    -541     1
# Comp:  2               HeI5876      0.000      0.20    -541     1
# Comp:  2          [OIII]5007_d      0.000      0.26    -541     1
# Comp:  2            [OI]6300_d      2.731      0.26    -541     1
# Comp:  2           [NII]6583_d     0.1504      0.26    -541     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        26
#  comp.  1:       -46        38
#  comp.  2:      -179       205
# chi2/DOF: 1.370; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.22     -46    38
# Comp:  1                Halpha     0.8063      0.22     -46    38
# Comp:  2             [SII]6716    0.05932      0.37    -179   205
# Comp:  2             [SII]6731     0.9912      0.37    -179   205
# Comp:  2              HeII4687     0.9125      0.37    -179   205
# Comp:  2               HeI5876     0.3631      0.37    -179   205
# Comp:  2          [OIII]5007_d     0.8459      0.47    -179   205
# Comp:  2            [OI]6300_d      0.000      0.47    -179   205
# Comp:  2           [NII]6583_d      1.387      0.47    -179   205
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -18         1
#  comp.  2:      -139       153
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6010      0.20     -18     1
# Comp:  1                Halpha     0.8155      0.20     -18     1
# Comp:  2             [SII]6716     0.3927      0.32    -139   153
# Comp:  2             [SII]6731     0.8160      0.32    -139   153
# Comp:  2              HeII4687     0.4554      0.32    -139   153
# Comp:  2               HeI5876     0.5405      0.32    -139   153
# Comp:  2          [OIII]5007_d     0.7091      0.41    -139   153
# Comp:  2            [OI]6300_d     0.4224      0.41    -139   153
# Comp:  2           [NII]6583_d      1.281      0.41    -139   153
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -27         1
#  comp.  2:       -90       210
# chi2/DOF: 1.371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4729      0.20     -27     1
# Comp:  1                Halpha     0.4805      0.20     -27     1
# Comp:  2             [SII]6716     0.1981      0.37     -90   210
# Comp:  2             [SII]6731     0.9312      0.37     -90   210
# Comp:  2              HeII4687     0.6999      0.37     -90   210
# Comp:  2               HeI5876    0.06656      0.37     -90   210
# Comp:  2          [OIII]5007_d      1.217      0.47     -90   210
# Comp:  2            [OI]6300_d     0.8404      0.47     -90   210
# Comp:  2           [NII]6583_d      1.317      0.47     -90   210
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.3731199 , 0.23996462, 0.26114601, 0.43717661, 0.32439368,
#        0.2324731 , 0.34779539, 1.13164024, 0.48792044])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.17322884, 0.81000594, 0.30164643, 1.10145158, 0.52534737,
#        0.        , 0.83577731, 0.88415069, 1.36746859])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_9_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_9", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_9_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_9_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_9_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.011521    0.024815
# 1        Halpha  0.053871    0.015959
# 2     [SII]6716  0.020062    0.017368
# 3     [SII]6731  0.073254    0.029075
# 4      HeII4687  0.034939    0.021574
# 5       HeI5876  0.000000    0.015461
# 6  [OIII]5007_d  0.055585    0.023131
# 7    [OI]6300_d  0.058802    0.075262
# 8   [NII]6583_d  0.090946    0.032450
#           Name      Flux  Error_flux
# 0        Hbeta  0.011521    0.024815
# 1       Halpha  0.053871    0.015959
# 2    [SII]6716  0.020062    0.017368
# 3    [SII]6731  0.073254    0.029075
# 4     HeII4687  0.034939    0.021574
# 5      HeI5876  0.000000    0.015461
# 6   [OIII]4959  0.013896    0.023131
# 7   [OIII]5007  0.041689    0.023131
# 8     [OI]6300  0.044102    0.075262
# 9     [OI]6364  0.014701    0.075262
# 10   [NII]6548  0.022737    0.032450
# 11   [NII]6583  0.068210    0.032450

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0665069415430352
