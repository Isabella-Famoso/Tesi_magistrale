# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_12.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_12']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.06392871 0.07149339 0.06277667 ... 0.02853376 0.03088246 0.0343913 ] [0.00801512 0.00801512 0.00801512 ... 0.00801512 0.00801512 0.00801512]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
# chi2/DOF: 0.04369; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
# chi2/DOF: 0.01794; DOF: 1920; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-38.93541341,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9672; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.137      0.45     -55    56
# Comp:  1                Halpha      14.66      0.45     -55    56
# Comp:  2             [SII]6716      2.869      0.43     -66    45
# Comp:  2             [SII]6731      2.328      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.810      0.55     -66    45
# Comp:  2            [OI]6300_d      1.197      0.55     -66    45
# Comp:  2           [NII]6583_d      2.480      0.55     -66    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:   10.3; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  30.36; gas flux:     20 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  6.625; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  5.193; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  8.191; gas flux:      5 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.964; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  4.256; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -56        59
#  comp.  2:       -63        39
# chi2/DOF: 0.9597; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.164      0.46     -56    59
# Comp:  1                Halpha      15.11      0.46     -56    59
# Comp:  2             [SII]6716      2.819      0.42     -63    39
# Comp:  2             [SII]6731      2.064      0.42     -63    39
# Comp:  2              HeII4687    0.07030      0.42     -63    39
# Comp:  2               HeI5876      0.000      0.42     -63    39
# Comp:  2          [OIII]5007_d      5.219      0.53     -63    39
# Comp:  2            [OI]6300_d      1.447      0.53     -63    39
# Comp:  2           [NII]6583_d      2.376      0.53     -63    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        42
#  comp.  1:       -57        63
#  comp.  2:       -65        45
# chi2/DOF: 0.9584; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.310      0.46     -57    63
# Comp:  1                Halpha      15.45      0.46     -57    63
# Comp:  2             [SII]6716      2.943      0.43     -65    45
# Comp:  2             [SII]6731      2.043      0.43     -65    45
# Comp:  2              HeII4687     0.5586      0.43     -65    45
# Comp:  2               HeI5876      0.000      0.43     -65    45
# Comp:  2          [OIII]5007_d      4.324      0.55     -65    45
# Comp:  2            [OI]6300_d     0.9504      0.55     -65    45
# Comp:  2           [NII]6583_d      2.526      0.55     -65    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        29
#  comp.  1:       -55        53
#  comp.  2:       -66        49
# chi2/DOF: 0.9605; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.706      0.45     -55    53
# Comp:  1                Halpha      14.61      0.45     -55    53
# Comp:  2             [SII]6716      3.182      0.44     -66    49
# Comp:  2             [SII]6731      2.710      0.44     -66    49
# Comp:  2              HeII4687    0.08145      0.44     -66    49
# Comp:  2               HeI5876      0.000      0.44     -66    49
# Comp:  2          [OIII]5007_d      4.906      0.55     -66    49
# Comp:  2            [OI]6300_d     0.9350      0.55     -66    49
# Comp:  2           [NII]6583_d      2.576      0.55     -66    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -60        58
#  comp.  2:       -68        33
# chi2/DOF: 0.9582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.325      0.45     -60    58
# Comp:  1                Halpha      15.03      0.45     -60    58
# Comp:  2             [SII]6716      2.559      0.42     -68    33
# Comp:  2             [SII]6731      2.340      0.42     -68    33
# Comp:  2              HeII4687    0.05786      0.42     -68    33
# Comp:  2               HeI5876    0.02881      0.42     -68    33
# Comp:  2          [OIII]5007_d      4.922      0.53     -68    33
# Comp:  2            [OI]6300_d     0.9642      0.53     -68    33
# Comp:  2           [NII]6583_d      2.565      0.53     -68    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        61
#  comp.  1:       -60        59
#  comp.  2:       -70        46
# chi2/DOF: 0.9609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.990      0.46     -60    59
# Comp:  1                Halpha      14.76      0.46     -60    59
# Comp:  2             [SII]6716      2.892      0.43     -70    46
# Comp:  2             [SII]6731      2.613      0.43     -70    46
# Comp:  2              HeII4687      0.000      0.43     -70    46
# Comp:  2               HeI5876    0.09646      0.43     -70    46
# Comp:  2          [OIII]5007_d      4.893      0.55     -70    46
# Comp:  2            [OI]6300_d      1.421      0.55     -70    46
# Comp:  2           [NII]6583_d      2.576      0.55     -70    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -56        60
#  comp.  2:       -63        45
# chi2/DOF: 0.9615; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.596      0.46     -56    60
# Comp:  1                Halpha      15.37      0.46     -56    60
# Comp:  2             [SII]6716      2.652      0.43     -63    45
# Comp:  2             [SII]6731      2.226      0.43     -63    45
# Comp:  2              HeII4687      0.000      0.43     -63    45
# Comp:  2               HeI5876      0.000      0.43     -63    45
# Comp:  2          [OIII]5007_d      5.244      0.55     -63    45
# Comp:  2            [OI]6300_d      1.458      0.55     -63    45
# Comp:  2           [NII]6583_d      2.488      0.55     -63    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        40
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9623; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.875      0.45     -55    56
# Comp:  1                Halpha      15.00      0.45     -55    56
# Comp:  2             [SII]6716      2.934      0.43     -66    45
# Comp:  2             [SII]6731      2.160      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.984      0.55     -66    45
# Comp:  2            [OI]6300_d      1.333      0.55     -66    45
# Comp:  2           [NII]6583_d      2.389      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        19
#  comp.  1:       -54        59
#  comp.  2:       -63        41
# chi2/DOF: 0.9557; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.049      0.46     -54    59
# Comp:  1                Halpha      14.54      0.46     -54    59
# Comp:  2             [SII]6716      2.927      0.43     -63    41
# Comp:  2             [SII]6731      2.481      0.43     -63    41
# Comp:  2              HeII4687    0.01639      0.43     -63    41
# Comp:  2               HeI5876     0.3595      0.43     -63    41
# Comp:  2          [OIII]5007_d      5.289      0.54     -63    41
# Comp:  2            [OI]6300_d      1.412      0.54     -63    41
# Comp:  2           [NII]6583_d      2.474      0.54     -63    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -60        63
#  comp.  2:       -62        48
# chi2/DOF: 0.9574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.192      0.46     -60    63
# Comp:  1                Halpha      15.10      0.46     -60    63
# Comp:  2             [SII]6716      3.094      0.44     -62    48
# Comp:  2             [SII]6731      2.424      0.44     -62    48
# Comp:  2              HeII4687      0.000      0.44     -62    48
# Comp:  2               HeI5876     0.3714      0.44     -62    48
# Comp:  2          [OIII]5007_d      5.031      0.55     -62    48
# Comp:  2            [OI]6300_d     0.9890      0.55     -62    48
# Comp:  2           [NII]6583_d      2.722      0.55     -62    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -56        53
#  comp.  2:       -64        52
# chi2/DOF: 0.9601; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.661      0.45     -56    53
# Comp:  1                Halpha      14.85      0.45     -56    53
# Comp:  2             [SII]6716      3.197      0.44     -64    52
# Comp:  2             [SII]6731      2.281      0.44     -64    52
# Comp:  2              HeII4687    0.08242      0.44     -64    52
# Comp:  2               HeI5876     0.1767      0.44     -64    52
# Comp:  2          [OIII]5007_d      5.010      0.56     -64    52
# Comp:  2            [OI]6300_d      1.359      0.56     -64    52
# Comp:  2           [NII]6583_d      2.500      0.56     -64    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        15
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9633; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.824      0.45     -55    56
# Comp:  1                Halpha      14.62      0.45     -55    56
# Comp:  2             [SII]6716      2.718      0.43     -66    45
# Comp:  2             [SII]6731      2.209      0.43     -66    45
# Comp:  2              HeII4687    0.04692      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.580      0.55     -66    45
# Comp:  2            [OI]6300_d      1.134      0.55     -66    45
# Comp:  2           [NII]6583_d      2.604      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        48
#  comp.  1:       -54        48
#  comp.  2:       -58        48
# chi2/DOF: 0.9583; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.363      0.44     -54    48
# Comp:  1                Halpha      13.81      0.44     -54    48
# Comp:  2             [SII]6716      2.763      0.44     -58    48
# Comp:  2             [SII]6731      2.647      0.44     -58    48
# Comp:  2              HeII4687      0.000      0.44     -58    48
# Comp:  2               HeI5876      0.000      0.44     -58    48
# Comp:  2          [OIII]5007_d      4.761      0.55     -58    48
# Comp:  2            [OI]6300_d      1.296      0.55     -58    48
# Comp:  2           [NII]6583_d      2.428      0.55     -58    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -54        55
#  comp.  2:       -71        56
# chi2/DOF: 0.9632; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.094      0.45     -54    55
# Comp:  1                Halpha      14.81      0.45     -54    55
# Comp:  2             [SII]6716      3.075      0.45     -71    56
# Comp:  2             [SII]6731      2.237      0.45     -71    56
# Comp:  2              HeII4687      0.000      0.45     -71    56
# Comp:  2               HeI5876    0.08689      0.45     -71    56
# Comp:  2          [OIII]5007_d      5.004      0.57     -71    56
# Comp:  2            [OI]6300_d      1.142      0.57     -71    56
# Comp:  2           [NII]6583_d      2.637      0.57     -71    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -58        62
#  comp.  2:       -65        42
# chi2/DOF: 0.9570; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.112      0.46     -58    62
# Comp:  1                Halpha      14.93      0.46     -58    62
# Comp:  2             [SII]6716      2.652      0.43     -65    42
# Comp:  2             [SII]6731      2.486      0.43     -65    42
# Comp:  2              HeII4687      0.000      0.43     -65    42
# Comp:  2               HeI5876      0.000      0.43     -65    42
# Comp:  2          [OIII]5007_d      4.703      0.54     -65    42
# Comp:  2            [OI]6300_d      1.473      0.54     -65    42
# Comp:  2           [NII]6583_d      2.457      0.54     -65    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -60        59
#  comp.  2:       -67        52
# chi2/DOF: 0.9599; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.449      0.46     -60    59
# Comp:  1                Halpha      14.92      0.46     -60    59
# Comp:  2             [SII]6716      2.926      0.44     -67    52
# Comp:  2             [SII]6731      2.241      0.44     -67    52
# Comp:  2              HeII4687     0.1650      0.44     -67    52
# Comp:  2               HeI5876      0.000      0.44     -67    52
# Comp:  2          [OIII]5007_d      5.109      0.56     -67    52
# Comp:  2            [OI]6300_d     0.8931      0.56     -67    52
# Comp:  2           [NII]6583_d      2.759      0.56     -67    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -57        56
#  comp.  2:       -69        38
# chi2/DOF: 0.9599; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.108      0.45     -57    56
# Comp:  1                Halpha      14.80      0.45     -57    56
# Comp:  2             [SII]6716      2.915      0.42     -69    38
# Comp:  2             [SII]6731      2.398      0.42     -69    38
# Comp:  2              HeII4687      0.000      0.42     -69    38
# Comp:  2               HeI5876      0.000      0.42     -69    38
# Comp:  2          [OIII]5007_d      5.167      0.53     -69    38
# Comp:  2            [OI]6300_d      1.036      0.53     -69    38
# Comp:  2           [NII]6583_d      2.384      0.53     -69    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -57        59
#  comp.  2:       -62        47
# chi2/DOF: 0.9610; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.376      0.46     -57    59
# Comp:  1                Halpha      15.30      0.46     -57    59
# Comp:  2             [SII]6716      2.871      0.43     -62    47
# Comp:  2             [SII]6731      2.558      0.43     -62    47
# Comp:  2              HeII4687      0.000      0.43     -62    47
# Comp:  2               HeI5876      0.000      0.43     -62    47
# Comp:  2          [OIII]5007_d      5.502      0.55     -62    47
# Comp:  2            [OI]6300_d      1.282      0.55     -62    47
# Comp:  2           [NII]6583_d      2.558      0.55     -62    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        32
#  comp.  1:       -57        55
#  comp.  2:       -63        35
# chi2/DOF: 0.9628; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.264      0.45     -57    55
# Comp:  1                Halpha      14.45      0.45     -57    55
# Comp:  2             [SII]6716      2.679      0.42     -63    35
# Comp:  2             [SII]6731      2.284      0.42     -63    35
# Comp:  2              HeII4687      0.000      0.42     -63    35
# Comp:  2               HeI5876      0.000      0.42     -63    35
# Comp:  2          [OIII]5007_d      5.065      0.53     -63    35
# Comp:  2            [OI]6300_d     0.9189      0.53     -63    35
# Comp:  2           [NII]6583_d      2.432      0.53     -63    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9611; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.680      0.45     -55    56
# Comp:  1                Halpha      15.45      0.45     -55    56
# Comp:  2             [SII]6716      2.836      0.43     -66    45
# Comp:  2             [SII]6731      2.167      0.43     -66    45
# Comp:  2              HeII4687     0.3967      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      5.055      0.55     -66    45
# Comp:  2            [OI]6300_d      1.029      0.55     -66    45
# Comp:  2           [NII]6583_d      2.605      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        71
#  comp.  1:       -58        64
#  comp.  2:       -63        48
# chi2/DOF: 0.9621; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.309      0.46     -58    64
# Comp:  1                Halpha      15.48      0.46     -58    64
# Comp:  2             [SII]6716      3.063      0.44     -63    48
# Comp:  2             [SII]6731      2.429      0.44     -63    48
# Comp:  2              HeII4687     0.1260      0.44     -63    48
# Comp:  2               HeI5876    0.03400      0.44     -63    48
# Comp:  2          [OIII]5007_d      5.080      0.55     -63    48
# Comp:  2            [OI]6300_d      1.182      0.55     -63    48
# Comp:  2           [NII]6583_d      2.531      0.55     -63    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -54        53
#  comp.  2:       -63        35
# chi2/DOF: 0.9616; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.936      0.45     -54    53
# Comp:  1                Halpha      14.84      0.45     -54    53
# Comp:  2             [SII]6716      2.611      0.42     -63    35
# Comp:  2             [SII]6731      2.102      0.42     -63    35
# Comp:  2              HeII4687     0.4009      0.42     -63    35
# Comp:  2               HeI5876      0.000      0.42     -63    35
# Comp:  2          [OIII]5007_d      4.529      0.53     -63    35
# Comp:  2            [OI]6300_d      1.294      0.53     -63    35
# Comp:  2           [NII]6583_d      2.132      0.53     -63    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -61        59
#  comp.  2:       -69        37
# chi2/DOF: 0.9616; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.736      0.46     -61    59
# Comp:  1                Halpha      14.88      0.46     -61    59
# Comp:  2             [SII]6716      2.742      0.42     -69    37
# Comp:  2             [SII]6731      2.519      0.42     -69    37
# Comp:  2              HeII4687     0.3326      0.42     -69    37
# Comp:  2               HeI5876      0.000      0.42     -69    37
# Comp:  2          [OIII]5007_d      5.157      0.53     -69    37
# Comp:  2            [OI]6300_d      1.245      0.53     -69    37
# Comp:  2           [NII]6583_d      2.290      0.53     -69    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        36
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9571; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.148      0.45     -55    56
# Comp:  1                Halpha      14.85      0.45     -55    56
# Comp:  2             [SII]6716      2.901      0.43     -66    45
# Comp:  2             [SII]6731      2.218      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876     0.6027      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.757      0.55     -66    45
# Comp:  2            [OI]6300_d     0.9741      0.55     -66    45
# Comp:  2           [NII]6583_d      2.583      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        27
#  comp.  1:       -52        52
#  comp.  2:       -63        47
# chi2/DOF: 0.9626; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.108      0.44     -52    52
# Comp:  1                Halpha      14.35      0.44     -52    52
# Comp:  2             [SII]6716      3.127      0.44     -63    47
# Comp:  2             [SII]6731      2.526      0.44     -63    47
# Comp:  2              HeII4687      0.000      0.44     -63    47
# Comp:  2               HeI5876    0.02987      0.44     -63    47
# Comp:  2          [OIII]5007_d      4.565      0.55     -63    47
# Comp:  2            [OI]6300_d      1.184      0.55     -63    47
# Comp:  2           [NII]6583_d      2.663      0.55     -63    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        15
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9601; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.305      0.45     -55    56
# Comp:  1                Halpha      14.91      0.45     -55    56
# Comp:  2             [SII]6716      2.622      0.43     -66    45
# Comp:  2             [SII]6731      2.302      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876     0.3133      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.533      0.55     -66    45
# Comp:  2            [OI]6300_d      1.205      0.55     -66    45
# Comp:  2           [NII]6583_d      2.578      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -49        55
#  comp.  2:       -65        50
# chi2/DOF: 0.9602; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.041      0.45     -49    55
# Comp:  1                Halpha      14.52      0.45     -49    55
# Comp:  2             [SII]6716      2.881      0.44     -65    50
# Comp:  2             [SII]6731      2.309      0.44     -65    50
# Comp:  2              HeII4687      0.000      0.44     -65    50
# Comp:  2               HeI5876      0.000      0.44     -65    50
# Comp:  2          [OIII]5007_d      4.780      0.56     -65    50
# Comp:  2            [OI]6300_d      1.254      0.56     -65    50
# Comp:  2           [NII]6583_d      2.319      0.56     -65    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        28
#  comp.  1:       -55        49
#  comp.  2:       -61        39
# chi2/DOF: 0.9568; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.693      0.44     -55    49
# Comp:  1                Halpha      13.98      0.44     -55    49
# Comp:  2             [SII]6716      2.764      0.42     -61    39
# Comp:  2             [SII]6731      1.986      0.42     -61    39
# Comp:  2              HeII4687    0.02409      0.42     -61    39
# Comp:  2               HeI5876     0.2784      0.42     -61    39
# Comp:  2          [OIII]5007_d      5.174      0.53     -61    39
# Comp:  2            [OI]6300_d      1.404      0.53     -61    39
# Comp:  2           [NII]6583_d      2.384      0.53     -61    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        22
#  comp.  1:       -55        56
#  comp.  2:       -66        44
# chi2/DOF: 0.9598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.399      0.45     -55    56
# Comp:  1                Halpha      15.06      0.45     -55    56
# Comp:  2             [SII]6716      3.047      0.43     -66    44
# Comp:  2             [SII]6731      2.469      0.43     -66    44
# Comp:  2              HeII4687    0.01130      0.43     -66    44
# Comp:  2               HeI5876     0.2029      0.43     -66    44
# Comp:  2          [OIII]5007_d      5.071      0.54     -66    44
# Comp:  2            [OI]6300_d      1.218      0.54     -66    44
# Comp:  2           [NII]6583_d      2.439      0.54     -66    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        23
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.036      0.45     -55    56
# Comp:  1                Halpha      15.37      0.45     -55    56
# Comp:  2             [SII]6716      2.812      0.43     -66    45
# Comp:  2             [SII]6731      2.478      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876    0.03514      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.798      0.55     -66    45
# Comp:  2            [OI]6300_d      1.088      0.55     -66    45
# Comp:  2           [NII]6583_d      2.462      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -55        61
#  comp.  2:       -68        45
# chi2/DOF: 0.9581; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.837      0.46     -55    61
# Comp:  1                Halpha      15.43      0.46     -55    61
# Comp:  2             [SII]6716      2.905      0.43     -68    45
# Comp:  2             [SII]6731      2.355      0.43     -68    45
# Comp:  2              HeII4687     0.2180      0.43     -68    45
# Comp:  2               HeI5876      0.000      0.43     -68    45
# Comp:  2          [OIII]5007_d      4.657      0.55     -68    45
# Comp:  2            [OI]6300_d      1.242      0.55     -68    45
# Comp:  2           [NII]6583_d      2.518      0.55     -68    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59       101
#  comp.  1:       -57        55
#  comp.  2:       -64        46
# chi2/DOF: 0.9593; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.463      0.45     -57    55
# Comp:  1                Halpha      14.25      0.45     -57    55
# Comp:  2             [SII]6716      2.624      0.43     -64    46
# Comp:  2             [SII]6731      2.482      0.43     -64    46
# Comp:  2              HeII4687   0.004619      0.43     -64    46
# Comp:  2               HeI5876      0.000      0.43     -64    46
# Comp:  2          [OIII]5007_d      4.732      0.55     -64    46
# Comp:  2            [OI]6300_d      1.034      0.55     -64    46
# Comp:  2           [NII]6583_d      2.518      0.55     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        74
#  comp.  1:       -55        60
#  comp.  2:       -62        53
# chi2/DOF: 0.9589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.642      0.46     -55    60
# Comp:  1                Halpha      15.03      0.46     -55    60
# Comp:  2             [SII]6716      2.906      0.44     -62    53
# Comp:  2             [SII]6731      2.392      0.44     -62    53
# Comp:  2              HeII4687     0.2889      0.44     -62    53
# Comp:  2               HeI5876   0.009262      0.44     -62    53
# Comp:  2          [OIII]5007_d      4.875      0.56     -62    53
# Comp:  2            [OI]6300_d     0.9584      0.56     -62    53
# Comp:  2           [NII]6583_d      2.427      0.56     -62    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        71
#  comp.  1:       -58        63
#  comp.  2:       -62        38
# chi2/DOF: 0.9567; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.955      0.46     -58    63
# Comp:  1                Halpha      15.45      0.46     -58    63
# Comp:  2             [SII]6716      2.685      0.42     -62    38
# Comp:  2             [SII]6731      2.281      0.42     -62    38
# Comp:  2              HeII4687     0.2369      0.42     -62    38
# Comp:  2               HeI5876     0.4547      0.42     -62    38
# Comp:  2          [OIII]5007_d      5.046      0.53     -62    38
# Comp:  2            [OI]6300_d      1.031      0.53     -62    38
# Comp:  2           [NII]6583_d      2.508      0.53     -62    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        21
#  comp.  1:       -55        56
#  comp.  2:       -66        46
# chi2/DOF: 0.9621; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.386      0.45     -55    56
# Comp:  1                Halpha      15.08      0.45     -55    56
# Comp:  2             [SII]6716      2.742      0.43     -66    46
# Comp:  2             [SII]6731      2.194      0.43     -66    46
# Comp:  2              HeII4687     0.2022      0.43     -66    46
# Comp:  2               HeI5876     0.1036      0.43     -66    46
# Comp:  2          [OIII]5007_d      4.627      0.55     -66    46
# Comp:  2            [OI]6300_d      1.371      0.55     -66    46
# Comp:  2           [NII]6583_d      2.806      0.55     -66    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       112
#  comp.  1:       -50        54
#  comp.  2:       -69        42
# chi2/DOF: 0.9620; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.998      0.45     -50    54
# Comp:  1                Halpha      14.50      0.45     -50    54
# Comp:  2             [SII]6716      2.886      0.43     -69    42
# Comp:  2             [SII]6731      2.149      0.43     -69    42
# Comp:  2              HeII4687      0.000      0.43     -69    42
# Comp:  2               HeI5876     0.1005      0.43     -69    42
# Comp:  2          [OIII]5007_d      4.613      0.54     -69    42
# Comp:  2            [OI]6300_d      1.141      0.54     -69    42
# Comp:  2           [NII]6583_d      2.425      0.54     -69    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -52        53
#  comp.  2:       -65        40
# chi2/DOF: 0.9588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.751      0.45     -52    53
# Comp:  1                Halpha      14.59      0.45     -52    53
# Comp:  2             [SII]6716      2.713      0.43     -65    40
# Comp:  2             [SII]6731      2.460      0.43     -65    40
# Comp:  2              HeII4687     0.3076      0.43     -65    40
# Comp:  2               HeI5876      0.000      0.43     -65    40
# Comp:  2          [OIII]5007_d      4.311      0.54     -65    40
# Comp:  2            [OI]6300_d      1.416      0.54     -65    40
# Comp:  2           [NII]6583_d      2.466      0.54     -65    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -54        50
#  comp.  2:       -66        33
# chi2/DOF: 0.9587; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.297      0.44     -54    50
# Comp:  1                Halpha      14.13      0.44     -54    50
# Comp:  2             [SII]6716      2.677      0.42     -66    33
# Comp:  2             [SII]6731      2.315      0.42     -66    33
# Comp:  2              HeII4687      0.000      0.42     -66    33
# Comp:  2               HeI5876     0.3535      0.42     -66    33
# Comp:  2          [OIII]5007_d      4.990      0.52     -66    33
# Comp:  2            [OI]6300_d      1.285      0.52     -66    33
# Comp:  2           [NII]6583_d      2.156      0.52     -66    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        31
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9619; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.844      0.45     -55    56
# Comp:  1                Halpha      14.58      0.45     -55    56
# Comp:  2             [SII]6716      3.119      0.43     -66    45
# Comp:  2             [SII]6731      2.357      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.590      0.55     -66    45
# Comp:  2            [OI]6300_d      1.069      0.55     -66    45
# Comp:  2           [NII]6583_d      2.372      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -54        51
#  comp.  2:       -64        46
# chi2/DOF: 0.9613; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.191      0.44     -54    51
# Comp:  1                Halpha      14.27      0.44     -54    51
# Comp:  2             [SII]6716      2.896      0.43     -64    46
# Comp:  2             [SII]6731      2.394      0.43     -64    46
# Comp:  2              HeII4687      0.000      0.43     -64    46
# Comp:  2               HeI5876      0.000      0.43     -64    46
# Comp:  2          [OIII]5007_d      5.233      0.55     -64    46
# Comp:  2            [OI]6300_d      1.531      0.55     -64    46
# Comp:  2           [NII]6583_d      2.524      0.55     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        90
#  comp.  1:       -55        55
#  comp.  2:       -66        45
# chi2/DOF: 0.9617; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.114      0.45     -55    55
# Comp:  1                Halpha      14.89      0.45     -55    55
# Comp:  2             [SII]6716      2.807      0.43     -66    45
# Comp:  2             [SII]6731      2.481      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876     0.1430      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.643      0.55     -66    45
# Comp:  2            [OI]6300_d      1.206      0.55     -66    45
# Comp:  2           [NII]6583_d      2.297      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        33
#  comp.  1:       -53        58
#  comp.  2:       -70        48
# chi2/DOF: 0.9603; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.226      0.45     -53    58
# Comp:  1                Halpha      15.34      0.45     -53    58
# Comp:  2             [SII]6716      3.138      0.44     -70    48
# Comp:  2             [SII]6731      2.548      0.44     -70    48
# Comp:  2              HeII4687      0.000      0.44     -70    48
# Comp:  2               HeI5876      0.000      0.44     -70    48
# Comp:  2          [OIII]5007_d      4.859      0.55     -70    48
# Comp:  2            [OI]6300_d     0.8598      0.55     -70    48
# Comp:  2           [NII]6583_d      2.629      0.55     -70    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        58
#  comp.  1:       -57        57
#  comp.  2:       -67        45
# chi2/DOF: 0.9616; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.693      0.45     -57    57
# Comp:  1                Halpha      14.69      0.45     -57    57
# Comp:  2             [SII]6716      2.714      0.43     -67    45
# Comp:  2             [SII]6731      2.207      0.43     -67    45
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.885      0.45     -54    55
# Comp:  1                Halpha      14.94      0.45     -54    55
# Comp:  2             [SII]6716      2.652      0.41     -62    29
# Comp:  2             [SII]6731      2.221      0.41     -62    29
# Comp:  2              HeII4687     0.1682      0.41     -62    29
# Comp:  2               HeI5876      0.000      0.41     -62    29
# Comp:  2          [OIII]5007_d      4.740      0.52     -62    29
# Comp:  2            [OI]6300_d      1.066      0.52     -62    29
# Comp:  2           [NII]6583_d      2.300      0.52     -62    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -59        63
#  comp.  2:       -68        50
# chi2/DOF: 0.9570; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.588      0.46     -59    63
# Comp:  1                Halpha      15.65      0.46     -59    63
# Comp:  2             [SII]6716      2.824      0.44     -68    50
# Comp:  2             [SII]6731      2.240      0.44     -68    50
# Comp:  2              HeII4687      0.000      0.44     -68    50
# Comp:  2               HeI5876      0.000      0.44     -68    50
# Comp:  2          [OIII]5007_d      4.373      0.56     -68    50
# Comp:  2            [OI]6300_d      1.431      0.56     -68    50
# Comp:  2           [NII]6583_d      2.576      0.56     -68    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        43
#  comp.  1:       -53        51
#  comp.  2:       -61        43
# chi2/DOF: 0.9612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.852      0.44     -53    51
# Comp:  1                Halpha      14.25      0.44     -53    51
# Comp:  2             [SII]6716      2.638      0.43     -61    43
# Comp:  2             [SII]6731      2.133      0.43     -61    43
# Comp:  2              HeII4687   0.003576      0.43     -61    43
# Comp:  2               HeI5876    0.06563      0.43     -61    43
# Comp:  2          [OIII]5007_d      5.241      0.54     -61    43
# Comp:  2            [OI]6300_d      1.340      0.54     -61    43
# Comp:  2           [NII]6583_d      2.310      0.54     -61    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        59
#  comp.  1:       -54        53
#  comp.  2:       -65        42
# chi2/DOF: 0.9636; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.756      0.44     -54    53
# Comp:  1                Halpha      14.68      0.44     -54    53
# Comp:  2             [SII]6716      2.825      0.43     -65    42
# Comp:  2             [SII]6731      2.190      0.43     -65    42
# Comp:  2              HeII4687      0.000      0.43     -65    42
# Comp:  2               HeI5876     0.2654      0.43     -65    42
# Comp:  2          [OIII]5007_d      4.580      0.54     -65    42
# Comp:  2            [OI]6300_d      1.101      0.54     -65    42
# Comp:  2           [NII]6583_d      2.356      0.54     -65    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        56
#  comp.  1:       -55        56
#  comp.  2:       -66        44
# chi2/DOF: 0.9630; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.456      0.45     -55    56
# Comp:  1                Halpha      14.87      0.45     -55    56
# Comp:  2             [SII]6716      2.889      0.43     -66    44
# Comp:  2             [SII]6731      2.321      0.43     -66    44
# Comp:  2              HeII4687    0.09939      0.43     -66    44
# Comp:  2               HeI5876      0.000      0.43     -66    44
# Comp:  2          [OIII]5007_d      4.736      0.55     -66    44
# Comp:  2            [OI]6300_d      1.203      0.55     -66    44
# Comp:  2           [NII]6583_d      2.550      0.55     -66    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        73
#  comp.  1:       -57        66
#  comp.  2:       -64        44
# chi2/DOF: 0.9632; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.700      0.47     -57    66
# Comp:  1                Halpha      15.47      0.47     -57    66
# Comp:  2             [SII]6716      2.850      0.43     -64    44
# Comp:  2             [SII]6731      2.203      0.43     -64    44
# Comp:  2              HeII4687    0.04132      0.43     -64    44
# Comp:  2               HeI5876     0.3024      0.43     -64    44
# Comp:  2          [OIII]5007_d      4.740      0.54     -64    44
# Comp:  2            [OI]6300_d      1.286      0.54     -64    44
# Comp:  2           [NII]6583_d      2.598      0.54     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        42
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9611; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.190      0.45     -55    56
# Comp:  1                Halpha      14.81      0.45     -55    56
# Comp:  2             [SII]6716      2.645      0.43     -66    45
# Comp:  2             [SII]6731      2.194      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876     0.1335      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.546      0.55     -66    45
# Comp:  2            [OI]6300_d      1.063      0.55     -66    45
# Comp:  2           [NII]6583_d      2.449      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        30
#  comp.  1:       -54        61
#  comp.  2:       -69        37
# chi2/DOF: 0.9627; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.600      0.46     -54    61
# Comp:  1                Halpha      15.20      0.46     -54    61
# Comp:  2             [SII]6716      2.878      0.42     -69    37
# Comp:  2             [SII]6731      1.981      0.42     -69    37
# Comp:  2              HeII4687    0.07247      0.42     -69    37
# Comp:  2               HeI5876      0.000      0.42     -69    37
# Comp:  2          [OIII]5007_d      4.548      0.53     -69    37
# Comp:  2            [OI]6300_d      1.156      0.53     -69    37
# Comp:  2           [NII]6583_d      2.322      0.53     -69    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        39
#  comp.  1:       -58        58
#  comp.  2:       -67        40
# chi2/DOF: 0.9608; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.570      0.45     -58    58
# Comp:  1                Halpha      15.23      0.45     -58    58
# Comp:  2             [SII]6716      2.628      0.43     -67    40
# Comp:  2             [SII]6731      2.079      0.43     -67    40
# Comp:  2              HeII4687      0.000      0.43     -67    40
# Comp:  2               HeI5876      0.000      0.43     -67    40
# Comp:  2          [OIII]5007_d      4.730      0.54     -67    40
# Comp:  2            [OI]6300_d      1.418      0.54     -67    40
# Comp:  2           [NII]6583_d      2.622      0.54     -67    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        26
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9627; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.149      0.45     -55    56
# Comp:  1                Halpha      14.84      0.45     -55    56
# Comp:  2             [SII]6716      2.665      0.43     -66    45
# Comp:  2             [SII]6731      2.023      0.43     -66    45
# Comp:  2              HeII4687      0.000      0.43     -66    45
# Comp:  2               HeI5876      0.000      0.43     -66    45
# Comp:  2          [OIII]5007_d      5.074      0.55     -66    45
# Comp:  2            [OI]6300_d      1.388      0.55     -66    45
# Comp:  2           [NII]6583_d      2.273      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59       100
#  comp.  1:       -55        56
#  comp.  2:       -66        45
# chi2/DOF: 0.9625; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.202      0.45     -55    56
# Comp:  1                Halpha      14.56      0.45     -55    56
# Comp:  2             [SII]6716      2.941      0.43     -66    45
# Comp:  2             [SII]6731      2.580      0.43     -66    45
# Comp:  2              HeII4687    0.02497      0.43     -66    45
# Comp:  2               HeI5876    0.08217      0.43     -66    45
# Comp:  2          [OIII]5007_d      4.687      0.55     -66    45
# Comp:  2            [OI]6300_d      1.270      0.55     -66    45
# Comp:  2           [NII]6583_d      2.491      0.55     -66    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        34
#  comp.  1:       -55        56
#  comp.  2:       -66        44
# chi2/DOF: 0.9627; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.645      0.45     -55    56
# Comp:  1                Halpha      14.70      0.45     -55    56
# Comp:  2             [SII]6716      2.844      0.43     -66    44
# Comp:  2             [SII]6731      2.474      0.43     -66    44
# Comp:  2              HeII4687      0.000      0.43     -66    44
# Comp:  2               HeI5876      0.000      0.43     -66    44
# Comp:  2          [OIII]5007_d      4.772      0.54     -66    44
# Comp:  2            [OI]6300_d      1.133      0.54     -66    44
# Comp:  2           [NII]6583_d      2.460      0.54     -66    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        38
#  comp.  1:       -54        47
#  comp.  2:       -59        49
# chi2/DOF: 0.9569; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.192      0.43     -54    47
# Comp:  1                Halpha      13.84      0.43     -54    47
# Comp:  2             [SII]6716      2.732      0.44     -59    49
# Comp:  2             [SII]6731      2.343      0.44     -59    49
# Comp:  2              HeII4687      0.000      0.44     -59    49
# Comp:  2               HeI5876     0.1082      0.44     -59    49
# Comp:  2          [OIII]5007_d      4.612      0.55     -59    49
# Comp:  2            [OI]6300_d      1.221      0.55     -59    49
# Comp:  2           [NII]6583_d      2.693      0.55     -59    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        43
#  comp.  1:       -59        57
#  comp.  2:       -68        45
# chi2/DOF: 0.9614; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.934      0.45     -59    57
# Comp:  1                Halpha      15.12      0.45     -59    57
# Comp:  2             [SII]6716      3.079      0.43     -68    45
# Comp:  2             [SII]6731      2.179      0.43     -68    45
# Comp:  2              HeII4687      0.000      0.43     -68    45
# Comp:  2               HeI5876     0.2631      0.43     -68    45
# Comp:  2          [OIII]5007_d      4.529      0.55     -68    45
# Comp:  2            [OI]6300_d      1.093      0.55     -68    45
# Comp:  2           [NII]6583_d      2.596      0.55     -68    45
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.6708404 , 0.64661451, 0.21993503, 0.24347969, 0.16067488,
#        0.1749774 , 0.32183345, 0.24414915, 0.20362136])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 5.20846174, 20.07248613,  4.01959686,  3.26833643,  0.        ,
#         0.        ,  5.02331791,  1.57339557,  3.40473357])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_12_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_12", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_12_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_12_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_12_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.205597    0.026481
# 1        Halpha  0.792335    0.025524
# 2     [SII]6716  0.158668    0.008682
# 3     [SII]6731  0.129013    0.009611
# 4      HeII4687  0.000000    0.006342
# 5       HeI5876  0.000000    0.006907
# 6  [OIII]5007_d  0.198289    0.012704
# 7    [OI]6300_d  0.062108    0.009637
# 8   [NII]6583_d  0.134397    0.008038
#           Name      Flux  Error_flux
# 0        Hbeta  0.205597    0.026481
# 1       Halpha  0.792335    0.025524
# 2    [SII]6716  0.158668    0.008682
# 3    [SII]6731  0.129013    0.009611
# 4     HeII4687  0.000000    0.006342
# 5      HeI5876  0.000000    0.006907
# 6   [OIII]4959  0.049572    0.012704
# 7   [OIII]5007  0.148717    0.012704
# 8     [OI]6300  0.046581    0.009637
# 9     [OI]6364  0.015527    0.009637
# 10   [NII]6548  0.033599    0.008038
# 11   [NII]6583  0.100798    0.008038

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03947366151267808
