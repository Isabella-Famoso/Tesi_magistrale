# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_16.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_16']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.01959298 0.02112782 0.01071952 ... 0.00695891 0.01241691 0.00828781] [0.00500945 0.00500945 0.00500945 ... 0.00500945 0.00500945 0.00500945]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -412         1
# chi2/DOF: 0.3523; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -396         1
# chi2/DOF: 0.1567; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-395.59291197,    0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -433         1
#  comp.  1:        20       180
#  comp.  2:        37       193
# chi2/DOF: 1.544; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716      0.000       1.6      37   193
# Comp:  2             [SII]6731      1.668       1.6      37   193
# Comp:  2              HeII4687      2.756       1.6      37   193
# Comp:  2               HeI5876      0.000       1.6      37   193
# Comp:  2          [OIII]5007_d      0.000       2.0      37   193
# Comp:  2            [OI]6300_d      0.000       2.0      37   193
# Comp:  2           [NII]6583_d      3.065       2.0      37   193
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.5021; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  0.822; gas flux:      3 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  0.693; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -435         1
#  comp.  1:       158       174
#  comp.  2:      -140        52
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.043       1.5     158   174
# Comp:  1                Halpha      1.419       1.5     158   174
# Comp:  2             [SII]6716      0.000       1.0    -140    52
# Comp:  2             [SII]6731      1.871       1.0    -140    52
# Comp:  2              HeII4687    0.04529       1.0    -140    52
# Comp:  2               HeI5876      0.000       1.0    -140    52
# Comp:  2          [OIII]5007_d      0.000       1.3    -140    52
# Comp:  2            [OI]6300_d      3.733       1.3    -140    52
# Comp:  2           [NII]6583_d     0.5410       1.3    -140    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -433        78
#  comp.  1:        18       183
#  comp.  2:        39       195
# chi2/DOF: 1.531; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.147       1.5      18   183
# Comp:  1                Halpha      2.336       1.5      18   183
# Comp:  2             [SII]6716      0.000       1.6      39   195
# Comp:  2             [SII]6731      3.574       1.6      39   195
# Comp:  2              HeII4687      3.258       1.6      39   195
# Comp:  2               HeI5876      0.000       1.6      39   195
# Comp:  2          [OIII]5007_d      0.000       2.0      39   195
# Comp:  2            [OI]6300_d      0.000       2.0      39   195
# Comp:  2           [NII]6583_d      4.733       2.0      39   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -432        52
#  comp.  1:        13       189
#  comp.  2:        39       196
# chi2/DOF: 1.539; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6      13   189
# Comp:  1                Halpha      1.596       1.6      13   189
# Comp:  2             [SII]6716      0.000       1.6      39   196
# Comp:  2             [SII]6731      0.000       1.6      39   196
# Comp:  2              HeII4687      3.395       1.6      39   196
# Comp:  2               HeI5876     0.4540       1.6      39   196
# Comp:  2          [OIII]5007_d     0.2764       2.0      39   196
# Comp:  2            [OI]6300_d      1.039       2.0      39   196
# Comp:  2           [NII]6583_d      2.602       2.0      39   196
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -434        41
#  comp.  1:        16       189
#  comp.  2:        35       196
# chi2/DOF: 1.536; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.462       1.6      16   189
# Comp:  1                Halpha     0.3754       1.6      16   189
# Comp:  2             [SII]6716    0.07984       1.6      35   196
# Comp:  2             [SII]6731      2.149       1.6      35   196
# Comp:  2              HeII4687      3.978       1.6      35   196
# Comp:  2               HeI5876      2.027       1.6      35   196
# Comp:  2          [OIII]5007_d      1.550       2.0      35   196
# Comp:  2            [OI]6300_d     0.8409       2.0      35   196
# Comp:  2           [NII]6583_d      3.997       2.0      35   196
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -421         1
#  comp.  1:        20       180
#  comp.  2:       -42       970
# chi2/DOF: 1.528; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.7      20   180
# Comp:  2             [SII]6716      0.000       7.8     -42   970
# Comp:  2             [SII]6731     0.1805       7.8     -42   970
# Comp:  2              HeII4687      12.79       3.5     -42   970
# Comp:  2               HeI5876      3.034       3.5     -42   970
# Comp:  2          [OIII]5007_d      9.738       4.2     -42   970
# Comp:  2            [OI]6300_d      11.24       4.3     -42   970
# Comp:  2           [NII]6583_d      1.321       4.4     -42   970
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -484       215
#  comp.  1:       325       136
#  comp.  2:        87       248
# chi2/DOF: 1.533; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.950       1.4     325   136
# Comp:  1                Halpha     0.4048       1.4     325   136
# Comp:  2             [SII]6716    0.07803       1.8      87   248
# Comp:  2             [SII]6731      2.728       1.8      87   248
# Comp:  2              HeII4687      3.066       1.8      87   248
# Comp:  2               HeI5876      2.808       1.8      87   248
# Comp:  2          [OIII]5007_d     0.6011       2.2      87   248
# Comp:  2            [OI]6300_d      4.652       2.2      87   248
# Comp:  2           [NII]6583_d      4.031       2.3      87   248
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -447       219
#  comp.  1:       153       269
#  comp.  2:       -14       117
# chi2/DOF: 1.534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.344       1.8     153   269
# Comp:  1                Halpha      1.618       1.9     153   269
# Comp:  2             [SII]6716    0.03057       1.3     -14   117
# Comp:  2             [SII]6731      1.835       1.3     -14   117
# Comp:  2              HeII4687      2.527       1.3     -14   117
# Comp:  2               HeI5876      1.185       1.3     -14   117
# Comp:  2          [OIII]5007_d      0.000       1.6     -14   117
# Comp:  2            [OI]6300_d      0.000       1.6     -14   117
# Comp:  2           [NII]6583_d      2.880       1.6     -14   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -433         1
#  comp.  1:        20       180
#  comp.  2:        37       193
# chi2/DOF: 1.539; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716      0.000       1.6      37   193
# Comp:  2             [SII]6731      1.186       1.6      37   193
# Comp:  2              HeII4687      2.278       1.6      37   193
# Comp:  2               HeI5876      1.446       1.6      37   193
# Comp:  2          [OIII]5007_d     0.9594       2.0      37   193
# Comp:  2            [OI]6300_d      2.260       2.0      37   193
# Comp:  2           [NII]6583_d      4.167       2.0      37   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -432         1
#  comp.  1:      -401       224
#  comp.  2:        59        70
# chi2/DOF: 1.531; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.042       1.7    -401   224
# Comp:  1                Halpha      2.514       1.7    -401   224
# Comp:  2             [SII]6716      0.000       1.1      59    70
# Comp:  2             [SII]6731      0.000       1.1      59    70
# Comp:  2              HeII4687      1.961       1.1      59    70
# Comp:  2               HeI5876      2.983       1.1      59    70
# Comp:  2          [OIII]5007_d      0.000       1.4      59    70
# Comp:  2            [OI]6300_d      0.000       1.4      59    70
# Comp:  2           [NII]6583_d      2.111       1.4      59    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -431        89
#  comp.  1:        13       173
#  comp.  2:        43       192
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      13   173
# Comp:  1                Halpha     0.7979       1.5      13   173
# Comp:  2             [SII]6716      0.000       1.6      43   192
# Comp:  2             [SII]6731      1.561       1.6      43   192
# Comp:  2              HeII4687      2.291       1.6      43   192
# Comp:  2               HeI5876      0.000       1.6      43   192
# Comp:  2          [OIII]5007_d      0.000       2.0      43   192
# Comp:  2            [OI]6300_d      0.000       2.0      43   192
# Comp:  2           [NII]6583_d      3.251       2.0      43   192
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -465         1
#  comp.  1:        20       180
#  comp.  2:      -157       235
# chi2/DOF: 1.533; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716      0.000       1.8    -157   235
# Comp:  2             [SII]6731     0.6183       1.8    -157   235
# Comp:  2              HeII4687      5.368       1.7    -157   235
# Comp:  2               HeI5876      1.126       1.7    -157   235
# Comp:  2          [OIII]5007_d      0.000       2.2    -157   235
# Comp:  2            [OI]6300_d      4.607       2.2    -157   235
# Comp:  2           [NII]6583_d      3.936       2.2    -157   235
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -433       116
#  comp.  1:        -2       190
#  comp.  2:        51       185
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6      -2   190
# Comp:  1                Halpha     0.5690       1.6      -2   190
# Comp:  2             [SII]6716     0.4985       1.6      51   185
# Comp:  2             [SII]6731     0.1955       1.6      51   185
# Comp:  2              HeII4687     0.9150       1.6      51   185
# Comp:  2               HeI5876     0.9342       1.6      51   185
# Comp:  2          [OIII]5007_d      0.000       2.0      51   185
# Comp:  2            [OI]6300_d      0.000       2.0      51   185
# Comp:  2           [NII]6583_d      3.503       2.0      51   185
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -437         1
#  comp.  1:      -100       234
#  comp.  2:        39       137
# chi2/DOF: 1.536; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.7    -100   234
# Comp:  1                Halpha      0.000       1.7    -100   234
# Comp:  2             [SII]6716     0.4078       1.4      39   137
# Comp:  2             [SII]6731      3.273       1.4      39   137
# Comp:  2              HeII4687      2.476       1.4      39   137
# Comp:  2               HeI5876      0.000       1.4      39   137
# Comp:  2          [OIII]5007_d     0.2066       1.7      39   137
# Comp:  2            [OI]6300_d      0.000       1.7      39   137
# Comp:  2           [NII]6583_d      2.628       1.7      39   137
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -454         1
#  comp.  1:      -331       321
#  comp.  2:       132       181
# chi2/DOF: 1.534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.418       2.0    -331   321
# Comp:  1                Halpha     0.3968       2.1    -331   321
# Comp:  2             [SII]6716      0.000       1.5     132   181
# Comp:  2             [SII]6731      0.000       1.5     132   181
# Comp:  2              HeII4687      4.233       1.5     132   181
# Comp:  2               HeI5876      0.000       1.5     132   181
# Comp:  2          [OIII]5007_d      0.000       1.9     132   181
# Comp:  2            [OI]6300_d     0.7171       1.9     132   181
# Comp:  2           [NII]6583_d      4.848       2.0     132   181
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -372        92
#  comp.  1:      -351       267
#  comp.  2:        38       119
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.8    -351   267
# Comp:  1                Halpha      2.809       1.9    -351   267
# Comp:  2             [SII]6716     0.2401       1.3      38   119
# Comp:  2             [SII]6731      0.000       1.3      38   119
# Comp:  2              HeII4687      3.459       1.3      38   119
# Comp:  2               HeI5876      0.000       1.3      38   119
# Comp:  2          [OIII]5007_d      1.571       1.6      38   119
# Comp:  2            [OI]6300_d      0.000       1.6      38   119
# Comp:  2           [NII]6583_d      1.710       1.7      38   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -440         1
#  comp.  1:       268         1
#  comp.  2:       195       104
# chi2/DOF: 1.529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.728      0.90     268     1
# Comp:  1                Halpha      0.000      0.90     268     1
# Comp:  2             [SII]6716     0.3022       1.2     195   104
# Comp:  2             [SII]6731     0.1027       1.2     195   104
# Comp:  2              HeII4687      2.070       1.2     195   104
# Comp:  2               HeI5876      3.320       1.2     195   104
# Comp:  2          [OIII]5007_d      0.000       1.6     195   104
# Comp:  2            [OI]6300_d     0.7510       1.6     195   104
# Comp:  2           [NII]6583_d      3.996       1.6     195   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -571        56
#  comp.  1:       459       339
#  comp.  2:      -125       287
# chi2/DOF: 1.533; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.176       2.1     459   339
# Comp:  1                Halpha      0.000       2.9     459   339
# Comp:  2             [SII]6716      0.000       2.0    -125   287
# Comp:  2             [SII]6731    0.08865       2.0    -125   287
# Comp:  2              HeII4687      2.672       1.9    -125   287
# Comp:  2               HeI5876      0.000       1.9    -125   287
# Comp:  2          [OIII]5007_d     0.6888       2.4    -125   287
# Comp:  2            [OI]6300_d      0.000       2.4    -125   287
# Comp:  2           [NII]6583_d      3.162       3.4    -125   287
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -428         1
#  comp.  1:        20      1000
#  comp.  2:       421      1000
# chi2/DOF: 1.531; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       3.5      20  1000
# Comp:  1                Halpha      0.000       5.8      20  1000
# Comp:  2             [SII]6716     0.1066       8.2     421  1000
# Comp:  2             [SII]6731      3.775       8.2     421  1000
# Comp:  2              HeII4687      14.88       3.5     421  1000
# Comp:  2               HeI5876      2.738       3.5     421  1000
# Comp:  2          [OIII]5007_d      6.024       4.3     421  1000
# Comp:  2            [OI]6300_d      0.000       4.3     421  1000
# Comp:  2           [NII]6583_d      2.314       6.4     421  1000
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -434        22
#  comp.  1:        20       181
#  comp.  2:        37       192
# chi2/DOF: 1.537; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.608       1.5      20   181
# Comp:  1                Halpha      2.225       1.5      20   181
# Comp:  2             [SII]6716      0.000       1.6      37   192
# Comp:  2             [SII]6731      1.274       1.6      37   192
# Comp:  2              HeII4687      3.151       1.6      37   192
# Comp:  2               HeI5876      0.000       1.6      37   192
# Comp:  2          [OIII]5007_d    0.09137       2.0      37   192
# Comp:  2            [OI]6300_d      0.000       2.0      37   192
# Comp:  2           [NII]6583_d      2.212       2.0      37   192
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -402        41
#  comp.  1:     -1876       149
#  comp.  2:        77       141
# chi2/DOF: 1.536; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3204       1.4   -1876   149
# Comp:  1                Halpha      1.301       1.4   -1876   149
# Comp:  2             [SII]6716     0.2138       1.4      77   141
# Comp:  2             [SII]6731      2.044       1.4      77   141
# Comp:  2              HeII4687      1.096       1.4      77   141
# Comp:  2               HeI5876      2.579       1.4      77   141
# Comp:  2          [OIII]5007_d      0.000       1.8      77   141
# Comp:  2            [OI]6300_d      0.000       1.8      77   141
# Comp:  2           [NII]6583_d      3.651       1.8      77   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -475       101
#  comp.  1:      -236       119
#  comp.  2:        70       334
# chi2/DOF: 1.522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.407       1.3    -236   119
# Comp:  1                Halpha      3.651       1.3    -236   119
# Comp:  2             [SII]6716     0.1635       2.2      70   334
# Comp:  2             [SII]6731      1.617       2.2      70   334
# Comp:  2              HeII4687     0.4390       2.1      70   334
# Comp:  2               HeI5876      0.000       2.1      70   334
# Comp:  2          [OIII]5007_d      0.000       2.6      70   334
# Comp:  2            [OI]6300_d      2.127       2.6      70   334
# Comp:  2           [NII]6583_d      7.611       2.6      70   334
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -431         1
#  comp.  1:      -137       389
#  comp.  2:      -143       375
# chi2/DOF: 1.534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 59; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.891       2.2    -137   389
# Comp:  1                Halpha     0.8997       2.4    -137   389
# Comp:  2             [SII]6716      0.000       2.5    -143   375
# Comp:  2             [SII]6731      0.000       2.5    -143   375
# Comp:  2              HeII4687      3.953       2.2    -143   375
# Comp:  2               HeI5876      0.000       2.2    -143   375
# Comp:  2          [OIII]5007_d      0.000       2.7    -143   375
# Comp:  2            [OI]6300_d      7.801       2.7    -143   375
# Comp:  2           [NII]6583_d      5.603       2.9    -143   375
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -414       210
#  comp.  1:      -256       144
#  comp.  2:      -302       323
# chi2/DOF: 1.522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.046       1.4    -256   144
# Comp:  1                Halpha      4.170       1.4    -256   144
# Comp:  2             [SII]6716      0.000       2.2    -302   323
# Comp:  2             [SII]6731     0.3666       2.2    -302   323
# Comp:  2              HeII4687      6.951       2.0    -302   323
# Comp:  2               HeI5876      2.319       2.0    -302   323
# Comp:  2          [OIII]5007_d      0.000       2.5    -302   323
# Comp:  2            [OI]6300_d      0.000       2.5    -302   323
# Comp:  2           [NII]6583_d      3.876       2.6    -302   323
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -439         1
#  comp.  1:       -26         6
#  comp.  2:        29       366
# chi2/DOF: 1.537; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.91     -26     6
# Comp:  1                Halpha     0.2147      0.91     -26     6
# Comp:  2             [SII]6716      0.000       2.4      29   366
# Comp:  2             [SII]6731      2.489       2.4      29   366
# Comp:  2              HeII4687      6.656       2.1      29   366
# Comp:  2               HeI5876      3.026       2.1      29   366
# Comp:  2          [OIII]5007_d      4.066       2.7      29   366
# Comp:  2            [OI]6300_d      0.000       2.7      29   366
# Comp:  2           [NII]6583_d      2.374       2.7      29   366
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -432        74
#  comp.  1:        19       179
#  comp.  2:        39       196
# chi2/DOF: 1.527; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3350       1.5      19   179
# Comp:  1                Halpha      0.000       1.5      19   179
# Comp:  2             [SII]6716     0.2709       1.6      39   196
# Comp:  2             [SII]6731      2.148       1.6      39   196
# Comp:  2              HeII4687      3.853       1.6      39   196
# Comp:  2               HeI5876      1.641       1.6      39   196
# Comp:  2          [OIII]5007_d      0.000       2.0      39   196
# Comp:  2            [OI]6300_d     0.3957       2.0      39   196
# Comp:  2           [NII]6583_d      3.987       2.0      39   196
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -420         1
#  comp.  1:      -309       664
#  comp.  2:      -184         1
# chi2/DOF: 1.532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.64       2.9    -309   664
# Comp:  1                Halpha      6.907       2.9    -309   664
# Comp:  2             [SII]6716     0.1281      0.90    -184     1
# Comp:  2             [SII]6731      0.000      0.90    -184     1
# Comp:  2              HeII4687     0.1463      0.90    -184     1
# Comp:  2               HeI5876      0.000      0.90    -184     1
# Comp:  2          [OIII]5007_d     0.5337       1.1    -184     1
# Comp:  2            [OI]6300_d      3.762       1.1    -184     1
# Comp:  2           [NII]6583_d     0.5292       1.2    -184     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -442       208
#  comp.  1:       325       714
#  comp.  2:        -7       305
# chi2/DOF: 1.522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.33       3.0     325   714
# Comp:  1                Halpha     0.7482       4.3     325   714
# Comp:  2             [SII]6716      0.000       2.1      -7   305
# Comp:  2             [SII]6731      1.979       2.1      -7   305
# Comp:  2              HeII4687      2.871       2.0      -7   305
# Comp:  2               HeI5876      2.103       2.0      -7   305
# Comp:  2          [OIII]5007_d      4.946       2.5      -7   305
# Comp:  2            [OI]6300_d     0.8635       2.5      -7   305
# Comp:  2           [NII]6583_d      3.101       3.6      -7   305
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -428         1
#  comp.  1:       302       315
#  comp.  2:        -3       237
# chi2/DOF: 1.532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.249       2.0     302   315
# Comp:  1                Halpha      0.000       2.1     302   315
# Comp:  2             [SII]6716      0.000       1.8      -3   237
# Comp:  2             [SII]6731      1.019       1.8      -3   237
# Comp:  2              HeII4687      2.659       1.7      -3   237
# Comp:  2               HeI5876      1.123       1.7      -3   237
# Comp:  2          [OIII]5007_d      0.000       2.2      -3   237
# Comp:  2            [OI]6300_d      0.000       2.2      -3   237
# Comp:  2           [NII]6583_d      5.048       2.3      -3   237
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -454       226
#  comp.  1:       205       131
#  comp.  2:       -18       338
# chi2/DOF: 1.529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.467       1.3     205   131
# Comp:  1                Halpha     0.3096       1.4     205   131
# Comp:  2             [SII]6716      0.000       2.3     -18   338
# Comp:  2             [SII]6731     0.9470       2.3     -18   338
# Comp:  2              HeII4687      4.381       2.1     -18   338
# Comp:  2               HeI5876      0.000       2.1     -18   338
# Comp:  2          [OIII]5007_d      0.000       2.6     -18   338
# Comp:  2            [OI]6300_d     0.3122       2.6     -18   338
# Comp:  2           [NII]6583_d      3.837       2.6     -18   338
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -538       214
#  comp.  1:       -16       320
#  comp.  2:        37       161
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.396       2.0     -16   320
# Comp:  1                Halpha      1.941       2.0     -16   320
# Comp:  2             [SII]6716     0.1169       1.5      37   161
# Comp:  2             [SII]6731      1.127       1.5      37   161
# Comp:  2              HeII4687      2.987       1.5      37   161
# Comp:  2               HeI5876      0.000       1.5      37   161
# Comp:  2          [OIII]5007_d     0.2516       1.9      37   161
# Comp:  2            [OI]6300_d      1.244       1.9      37   161
# Comp:  2           [NII]6583_d      3.137       1.9      37   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -433       260
#  comp.  1:       289       319
#  comp.  2:        -1       179
# chi2/DOF: 1.532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.738       2.0     289   319
# Comp:  1                Halpha      0.000       2.1     289   319
# Comp:  2             [SII]6716     0.2517       1.5      -1   179
# Comp:  2             [SII]6731     0.2949       1.5      -1   179
# Comp:  2              HeII4687      2.992       1.5      -1   179
# Comp:  2               HeI5876     0.6126       1.5      -1   179
# Comp:  2          [OIII]5007_d      0.000       1.9      -1   179
# Comp:  2            [OI]6300_d      0.000       1.9      -1   179
# Comp:  2           [NII]6583_d      3.106       2.0      -1   179
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -429       151
#  comp.  1:       119        82
#  comp.  2:        -8       162
# chi2/DOF: 1.528; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.314       1.1     119    82
# Comp:  1                Halpha      1.785       1.1     119    82
# Comp:  2             [SII]6716      0.000       1.5      -8   162
# Comp:  2             [SII]6731      2.560       1.5      -8   162
# Comp:  2              HeII4687      2.890       1.5      -8   162
# Comp:  2               HeI5876      0.000       1.5      -8   162
# Comp:  2          [OIII]5007_d     0.3743       1.9      -8   162
# Comp:  2            [OI]6300_d      0.000       1.9      -8   162
# Comp:  2           [NII]6583_d      3.618       1.9      -8   162
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -430       185
#  comp.  1:        20       180
#  comp.  2:        37       189
# chi2/DOF: 1.529; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716      0.000       1.6      37   189
# Comp:  2             [SII]6731      2.991       1.6      37   189
# Comp:  2              HeII4687      2.394       1.6      37   189
# Comp:  2               HeI5876    0.02532       1.6      37   189
# Comp:  2          [OIII]5007_d      0.000       2.0      37   189
# Comp:  2            [OI]6300_d     0.1408       2.0      37   189
# Comp:  2           [NII]6583_d      2.166       2.0      37   189
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -438         1
#  comp.  1:      -126        55
#  comp.  2:       -22       165
# chi2/DOF: 1.538; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.0    -126    55
# Comp:  1                Halpha      1.229       1.0    -126    55
# Comp:  2             [SII]6716     0.4921       1.5     -22   165
# Comp:  2             [SII]6731      3.289       1.5     -22   165
# Comp:  2              HeII4687      2.907       1.5     -22   165
# Comp:  2               HeI5876      0.000       1.5     -22   165
# Comp:  2          [OIII]5007_d      1.895       1.9     -22   165
# Comp:  2            [OI]6300_d      0.000       1.9     -22   165
# Comp:  2           [NII]6583_d      3.665       1.9     -22   165
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -421        69
#  comp.  1:      -282       257
#  comp.  2:        60       156
# chi2/DOF: 1.535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.981       1.8    -282   257
# Comp:  1                Halpha      5.793       1.8    -282   257
# Comp:  2             [SII]6716     0.1049       1.4      60   156
# Comp:  2             [SII]6731      2.268       1.4      60   156
# Comp:  2              HeII4687      1.732       1.4      60   156
# Comp:  2               HeI5876      0.000       1.4      60   156
# Comp:  2          [OIII]5007_d     0.3632       1.8      60   156
# Comp:  2            [OI]6300_d      0.000       1.8      60   156
# Comp:  2           [NII]6583_d      3.281       1.9      60   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -478        44
#  comp.  1:        87       268
#  comp.  2:       -80       193
# chi2/DOF: 1.527; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.820       1.8      87   268
# Comp:  1                Halpha      1.778       1.9      87   268
# Comp:  2             [SII]6716      0.000       1.6     -80   193
# Comp:  2             [SII]6731      1.209       1.6     -80   193
# Comp:  2              HeII4687      2.006       1.6     -80   193
# Comp:  2               HeI5876      0.000       1.6     -80   193
# Comp:  2          [OIII]5007_d      1.103       2.0     -80   193
# Comp:  2            [OI]6300_d      2.699       2.0     -80   193
# Comp:  2           [NII]6583_d      3.557       2.0     -80   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -442        63
#  comp.  1:      -296       220
#  comp.  2:        67       116
# chi2/DOF: 1.531; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.546       1.7    -296   220
# Comp:  1                Halpha      1.306       1.7    -296   220
# Comp:  2             [SII]6716    0.01705       1.3      67   116
# Comp:  2             [SII]6731      1.528       1.3      67   116
# Comp:  2              HeII4687      2.774       1.3      67   116
# Comp:  2               HeI5876      3.505       1.3      67   116
# Comp:  2          [OIII]5007_d      1.002       1.6      67   116
# Comp:  2            [OI]6300_d      0.000       1.6      67   116
# Comp:  2           [NII]6583_d      3.272       1.6      67   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -430       522
#  comp.  1:       214       284
#  comp.  2:        59       124
# chi2/DOF: 1.533; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.594       1.9     214   284
# Comp:  1                Halpha      1.014       1.9     214   284
# Comp:  2             [SII]6716      0.000       1.3      59   124
# Comp:  2             [SII]6731      2.120       1.3      59   124
# Comp:  2              HeII4687      2.937       1.3      59   124
# Comp:  2               HeI5876      2.178       1.3      59   124
# Comp:  2          [OIII]5007_d      0.000       1.7      59   124
# Comp:  2            [OI]6300_d      1.423       1.7      59   124
# Comp:  2           [NII]6583_d      2.633       1.7      59   124
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -388         1
#  comp.  1:       -94         1
#  comp.  2:      -431       346
# chi2/DOF: 1.521; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 83; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.592      0.90     -94     1
# Comp:  1                Halpha      0.000      0.91     -94     1
# Comp:  2             [SII]6716      0.000       2.3    -431   346
# Comp:  2             [SII]6731      0.000       2.3    -431   346
# Comp:  2              HeII4687      8.693       2.1    -431   346
# Comp:  2               HeI5876      0.000       2.1    -431   346
# Comp:  2          [OIII]5007_d     0.1150       2.6    -431   346
# Comp:  2            [OI]6300_d      6.164       2.6    -431   346
# Comp:  2           [NII]6583_d      0.000       2.7    -431   346
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -454         1
#  comp.  1:      -451       270
#  comp.  2:      -440       489
# chi2/DOF: 1.532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.9    -451   270
# Comp:  1                Halpha      3.392       2.0    -451   270
# Comp:  2             [SII]6716      0.000       3.3    -440   489
# Comp:  2             [SII]6731     0.7214       3.3    -440   489
# Comp:  2              HeII4687      10.21       2.5    -440   489
# Comp:  2               HeI5876      0.000       2.5    -440   489
# Comp:  2          [OIII]5007_d     0.9807       3.1    -440   489
# Comp:  2            [OI]6300_d      0.000       3.1    -440   489
# Comp:  2           [NII]6583_d      1.586       3.3    -440   489
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -480        66
#  comp.  1:       -55       189
#  comp.  2:       151       143
# chi2/DOF: 1.534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.538       1.6     -55   189
# Comp:  1                Halpha      2.377       1.6     -55   189
# Comp:  2             [SII]6716      0.000       1.4     151   143
# Comp:  2             [SII]6731     0.8696       1.4     151   143
# Comp:  2              HeII4687      2.874       1.4     151   143
# Comp:  2               HeI5876      0.000       1.4     151   143
# Comp:  2          [OIII]5007_d      2.872       1.8     151   143
# Comp:  2            [OI]6300_d      0.000       1.8     151   143
# Comp:  2           [NII]6583_d      0.000       1.8     151   143
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -434        48
#  comp.  1:        20       180
#  comp.  2:        40       200
# chi2/DOF: 1.537; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716     0.8929       1.6      40   200
# Comp:  2             [SII]6731      2.635       1.6      40   200
# Comp:  2              HeII4687      3.701       1.6      40   200
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.4    -325   137
# Comp:  1                Halpha      4.274       1.4    -325   137
# Comp:  2             [SII]6716      0.000       2.0     -93   283
# Comp:  2             [SII]6731      2.600       2.0     -93   283
# Comp:  2              HeII4687      5.770       1.9     -93   283
# Comp:  2               HeI5876      0.000       1.9     -93   283
# Comp:  2          [OIII]5007_d     0.1966       2.4     -93   283
# Comp:  2            [OI]6300_d      0.000       2.4     -93   283
# Comp:  2           [NII]6583_d      1.672       2.4     -93   283
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -435        72
#  comp.  1:       -88        66
#  comp.  2:        81       207
# chi2/DOF: 1.525; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.246       1.1     -88    66
# Comp:  1                Halpha      1.585       1.1     -88    66
# Comp:  2             [SII]6716      0.000       1.6      81   207
# Comp:  2             [SII]6731      2.672       1.6      81   207
# Comp:  2              HeII4687      3.963       1.6      81   207
# Comp:  2               HeI5876      0.000       1.6      81   207
# Comp:  2          [OIII]5007_d      1.088       2.1      81   207
# Comp:  2            [OI]6300_d      3.149       2.1      81   207
# Comp:  2           [NII]6583_d      4.788       2.1      81   207
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -409       125
#  comp.  1:      -248       233
#  comp.  2:        26       181
# chi2/DOF: 1.534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.153       1.7    -248   233
# Comp:  1                Halpha      4.557       1.7    -248   233
# Comp:  2             [SII]6716     0.8806       1.5      26   181
# Comp:  2             [SII]6731      1.826       1.5      26   181
# Comp:  2              HeII4687      3.715       1.5      26   181
# Comp:  2               HeI5876     0.5685       1.5      26   181
# Comp:  2          [OIII]5007_d      0.000       1.9      26   181
# Comp:  2            [OI]6300_d      1.071       1.9      26   181
# Comp:  2           [NII]6583_d      3.839       2.0      26   181
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -402         1
#  comp.  1:      -181       215
#  comp.  2:       -91       389
# chi2/DOF: 1.527; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.577       1.7    -181   215
# Comp:  1                Halpha      2.821       1.7    -181   215
# Comp:  2             [SII]6716     0.1164       2.6     -91   389
# Comp:  2             [SII]6731      1.247       2.6     -91   389
# Comp:  2              HeII4687      8.322       2.2     -91   389
# Comp:  2               HeI5876      2.366       2.2     -91   389
# Comp:  2          [OIII]5007_d      6.815       2.8     -91   389
# Comp:  2            [OI]6300_d      0.000       2.8     -91   389
# Comp:  2           [NII]6583_d      4.304       2.8     -91   389
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -464         1
#  comp.  1:      2020         1
#  comp.  2:       208       212
# chi2/DOF: 1.524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 75; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.919      0.90    2020     1
# Comp:  1                Halpha      1.926      0.90    2020     1
# Comp:  2             [SII]6716      0.000       1.7     208   212
# Comp:  2             [SII]6731     0.6781       1.7     208   212
# Comp:  2              HeII4687      4.075       1.7     208   212
# Comp:  2               HeI5876      3.071       1.7     208   212
# Comp:  2          [OIII]5007_d     0.7277       2.1     208   212
# Comp:  2            [OI]6300_d      1.364       2.1     208   212
# Comp:  2           [NII]6583_d      2.454       2.1     208   212
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -464         1
#  comp.  1:        20       180
#  comp.  2:        81       221
# chi2/DOF: 1.537; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.5      20   180
# Comp:  2             [SII]6716      0.000       1.7      81   221
# Comp:  2             [SII]6731      1.078       1.7      81   221
# Comp:  2              HeII4687      4.164       1.7      81   221
# Comp:  2               HeI5876      0.000       1.7      81   221
# Comp:  2          [OIII]5007_d      1.137       2.1      81   221
# Comp:  2            [OI]6300_d      0.000       2.1      81   221
# Comp:  2           [NII]6583_d      4.149       2.1      81   221
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -465       291
#  comp.  1:      -256      1000
#  comp.  2:        76        85
# chi2/DOF: 1.530; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      19.03       3.5    -256  1000
# Comp:  1                Halpha      10.59       3.7    -256  1000
# Comp:  2             [SII]6716     0.1567       1.2      76    85
# Comp:  2             [SII]6731      1.674       1.2      76    85
# Comp:  2              HeII4687      2.609       1.2      76    85
# Comp:  2               HeI5876      2.461       1.2      76    85
# Comp:  2          [OIII]5007_d      0.000       1.5      76    85
# Comp:  2            [OI]6300_d      0.000       1.5      76    85
# Comp:  2           [NII]6583_d      1.288       1.5      76    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -433        67
#  comp.  1:        25       188
#  comp.  2:        40       198
# chi2/DOF: 1.539; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6      25   188
# Comp:  1                Halpha     0.3360       1.6      25   188
# Comp:  2             [SII]6716     0.1735       1.6      40   198
# Comp:  2             [SII]6731      2.301       1.6      40   198
# Comp:  2              HeII4687      3.125       1.6      40   198
# Comp:  2               HeI5876      0.000       1.6      40   198
# Comp:  2          [OIII]5007_d     0.3257       2.0      40   198
# Comp:  2            [OI]6300_d      0.000       2.0      40   198
# Comp:  2           [NII]6583_d      4.246       2.0      40   198
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -187       597
#  comp.  1:       190       184
#  comp.  2:        53       156
# chi2/DOF: 1.537; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.574       1.6     190   184
# Comp:  1                Halpha      2.075       1.6     190   184
# Comp:  2             [SII]6716     0.1012       1.4      53   156
# Comp:  2             [SII]6731      2.820       1.4      53   156
# Comp:  2              HeII4687      2.641       1.4      53   156
# Comp:  2               HeI5876      0.000       1.4      53   156
# Comp:  2          [OIII]5007_d      0.000       1.8      53   156
# Comp:  2            [OI]6300_d      0.000       1.8      53   156
# Comp:  2           [NII]6583_d      4.162       1.8      53   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -478         1
#  comp.  1:        20       180
#  comp.  2:        -6       344
# chi2/DOF: 1.535; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5      20   180
# Comp:  1                Halpha      0.000       1.6      20   180
# Comp:  2             [SII]6716      0.000       2.3      -6   344
# Comp:  2             [SII]6731      4.354       2.3      -6   344
# Comp:  2              HeII4687      6.172       2.1      -6   344
# Comp:  2               HeI5876      0.000       2.1      -6   344
# Comp:  2          [OIII]5007_d    0.09422       2.6      -6   344
# Comp:  2            [OI]6300_d      0.000       2.6      -6   344
# Comp:  2           [NII]6583_d      5.662       2.6      -6   344
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -449         1
#  comp.  1:        20         1
#  comp.  2:       193       177
# chi2/DOF: 1.538; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.90      20     1
# Comp:  1                Halpha      0.000      0.90      20     1
# Comp:  2             [SII]6716      0.000       1.5     193   177
# Comp:  2             [SII]6731      1.908       1.5     193   177
# Comp:  2              HeII4687      3.429       1.5     193   177
# Comp:  2               HeI5876      0.000       1.5     193   177
# Comp:  2          [OIII]5007_d      4.409       1.9     193   177
# Comp:  2            [OI]6300_d     0.3816       1.9     193   177
# Comp:  2           [NII]6583_d      5.524       1.9     193   177
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -430        71
#  comp.  1:         6       174
#  comp.  2:        36       187
# chi2/DOF: 1.542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.5       6   174
# Comp:  1                Halpha     0.2263       1.5       6   174
# Comp:  2             [SII]6716      0.000       1.6      36   187
# Comp:  2             [SII]6731      1.271       1.6      36   187
# Comp:  2              HeII4687      2.694       1.6      36   187
# Comp:  2               HeI5876      0.000       1.6      36   187
# Comp:  2          [OIII]5007_d      1.273       2.0      36   187
# Comp:  2            [OI]6300_d      0.000       2.0      36   187
# Comp:  2           [NII]6583_d      4.216       2.0      36   187
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -277       491
#  comp.  1:      -135       152
#  comp.  2:       100       141
# chi2/DOF: 1.533; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.613       1.4    -135   152
# Comp:  1                Halpha      3.280       1.4    -135   152
# Comp:  2             [SII]6716     0.2064       1.4     100   141
# Comp:  2             [SII]6731      2.410       1.4     100   141
# Comp:  2              HeII4687      2.029       1.4     100   141
# Comp:  2               HeI5876      3.674       1.4     100   141
# Comp:  2          [OIII]5007_d      0.000       1.8     100   141
# Comp:  2            [OI]6300_d     0.6883       1.8     100   141
# Comp:  2           [NII]6583_d      3.210       1.8     100   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -407         1
#  comp.  1:      -195       197
#  comp.  2:        43        45
# chi2/DOF: 1.538; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6    -195   197
# Comp:  1                Halpha      2.587       1.6    -195   197
# Comp:  2             [SII]6716      0.000       1.0      43    45
# Comp:  2             [SII]6731      1.403       1.0      43    45
# Comp:  2              HeII4687      2.211       1.0      43    45
# Comp:  2               HeI5876      0.000       1.0      43    45
# Comp:  2          [OIII]5007_d     0.3748       1.3      43    45
# Comp:  2            [OI]6300_d     0.8090       1.3      43    45
# Comp:  2           [NII]6583_d      1.907       1.3      43    45
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([5.03623078, 2.63275692, 0.50909923, 1.57621916, 2.34373859,
#        1.57596321, 1.3422957 , 2.71965601, 2.30309755])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.        , 0.        , 0.        , 2.34232774, 2.6937422 ,
#        0.        , 0.        , 0.        , 4.20917565])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_16_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_16", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_16_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_16_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_16_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.000000    0.054043
# 1        Halpha  0.000000    0.028252
# 2     [SII]6716  0.000000    0.005463
# 3     [SII]6731  0.025135    0.016914
# 4      HeII4687  0.028906    0.025151
# 5       HeI5876  0.000000    0.016912
# 6  [OIII]5007_d  0.000000    0.014404
# 7    [OI]6300_d  0.000000    0.029184
# 8   [NII]6583_d  0.045168    0.024714
#           Name      Flux  Error_flux
# 0        Hbeta  0.000000    0.054043
# 1       Halpha  0.000000    0.028252
# 2    [SII]6716  0.000000    0.005463
# 3    [SII]6731  0.025135    0.016914
# 4     HeII4687  0.028906    0.025151
# 5      HeI5876  0.000000    0.016912
# 6   [OIII]4959  0.000000    0.014404
# 7   [OIII]5007  0.000000    0.014404
# 8     [OI]6300  0.000000    0.029184
# 9     [OI]6364  0.000000    0.029184
# 10   [NII]6548  0.011292    0.024714
# 11   [NII]6583  0.033876    0.024714

# %%
np.median(flux_rf_rebin)
# Out:
# 0.010730937953317421
