# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_15.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_15']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [ 0.01362075  0.012361    0.00196664 ...  0.00367544 -0.00148929
#   0.006989  ] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        71       230
# chi2/DOF: 0.3025; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:        18       244
# chi2/DOF: 0.1320; DOF: 1917; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 18.25100315, 244.21241271])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       270
#  comp.  1:       -42        63
#  comp.  2:       -58         1
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.010       1.1     -42    63
# Comp:  1                Halpha      6.847       1.1     -42    63
# Comp:  2             [SII]6716      1.092      0.97     -58     1
# Comp:  2             [SII]6731      2.275      0.97     -58     1
# Comp:  2              HeII4687      1.388      0.97     -58     1
# Comp:  2               HeI5876     0.6324      0.97     -58     1
# Comp:  2          [OIII]5007_d      1.255       1.2     -58     1
# Comp:  2            [OI]6300_d      1.940       1.2     -58     1
# Comp:  2           [NII]6583_d      2.117       1.2     -58     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  1.444; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  4.782; gas flux:      9 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  1.077; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.072; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.401; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.6387; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.9452; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.361; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.523; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -385       219
#  comp.  1:       -30        63
#  comp.  2:       -62         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.247       1.1     -30    63
# Comp:  1                Halpha      6.489       1.1     -30    63
# Comp:  2             [SII]6716      1.046      0.97     -62     1
# Comp:  2             [SII]6731      2.055      0.97     -62     1
# Comp:  2              HeII4687     0.5495      0.97     -62     1
# Comp:  2               HeI5876     0.8752      0.97     -62     1
# Comp:  2          [OIII]5007_d     0.7782       1.2     -62     1
# Comp:  2            [OI]6300_d      2.741       1.2     -62     1
# Comp:  2           [NII]6583_d      2.103       1.2     -62     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14       303
#  comp.  1:       -47        74
#  comp.  2:       -74        39
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.270       1.2     -47    74
# Comp:  1                Halpha      8.732       1.2     -47    74
# Comp:  2             [SII]6716      1.636       1.0     -74    39
# Comp:  2             [SII]6731      2.397       1.0     -74    39
# Comp:  2              HeII4687      1.801       1.0     -74    39
# Comp:  2               HeI5876      1.052       1.0     -74    39
# Comp:  2          [OIII]5007_d      2.225       1.3     -74    39
# Comp:  2            [OI]6300_d      1.314       1.3     -74    39
# Comp:  2           [NII]6583_d      1.958       1.3     -74    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25       138
#  comp.  1:       -39        52
#  comp.  2:       -68        68
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.684       1.1     -39    52
# Comp:  1                Halpha      6.918       1.1     -39    52
# Comp:  2             [SII]6716      2.170       1.2     -68    68
# Comp:  2             [SII]6731      2.829       1.2     -68    68
# Comp:  2              HeII4687      2.838       1.2     -68    68
# Comp:  2               HeI5876     0.3264       1.2     -68    68
# Comp:  2          [OIII]5007_d      2.067       1.5     -68    68
# Comp:  2            [OI]6300_d      2.215       1.5     -68    68
# Comp:  2           [NII]6583_d      3.374       1.5     -68    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       272
#  comp.  1:       -42        63
#  comp.  2:       -57        15
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.539       1.1     -42    63
# Comp:  1                Halpha      7.692       1.1     -42    63
# Comp:  2             [SII]6716     0.7217      0.99     -57    15
# Comp:  2             [SII]6731      2.628      0.99     -57    15
# Comp:  2              HeII4687      1.977      0.99     -57    15
# Comp:  2               HeI5876     0.5325      0.99     -57    15
# Comp:  2          [OIII]5007_d     0.8524       1.2     -57    15
# Comp:  2            [OI]6300_d      1.532       1.2     -57    15
# Comp:  2           [NII]6583_d      2.575       1.2     -57    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79       222
#  comp.  1:       -46        88
#  comp.  2:       -54        45
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.272       1.3     -46    88
# Comp:  1                Halpha      7.977       1.3     -46    88
# Comp:  2             [SII]6716      1.212       1.1     -54    45
# Comp:  2             [SII]6731      2.411       1.1     -54    45
# Comp:  2              HeII4687      1.414       1.1     -54    45
# Comp:  2               HeI5876     0.9039       1.1     -54    45
# Comp:  2          [OIII]5007_d      1.601       1.4     -54    45
# Comp:  2            [OI]6300_d      2.937       1.4     -54    45
# Comp:  2           [NII]6583_d      2.672       1.4     -54    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60       104
#  comp.  1:       -48        74
#  comp.  2:       105       241
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.407       1.2     -48    74
# Comp:  1                Halpha      7.374       1.2     -48    74
# Comp:  2             [SII]6716    0.09914       1.9     105   241
# Comp:  2             [SII]6731      6.122       1.9     105   241
# Comp:  2              HeII4687      2.474       1.9     105   241
# Comp:  2               HeI5876      3.499       1.9     105   241
# Comp:  2          [OIII]5007_d      0.000       2.4     105   241
# Comp:  2            [OI]6300_d      4.251       2.4     105   241
# Comp:  2           [NII]6583_d      1.451       2.4     105   241
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       135       310
#  comp.  1:       -45        50
#  comp.  2:       -54       110
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.160       1.1     -45    50
# Comp:  1                Halpha      5.432       1.1     -45    50
# Comp:  2             [SII]6716      2.178       1.4     -54   110
# Comp:  2             [SII]6731      3.425       1.4     -54   110
# Comp:  2              HeII4687      3.607       1.4     -54   110
# Comp:  2               HeI5876      0.000       1.4     -54   110
# Comp:  2          [OIII]5007_d     0.2257       1.7     -54   110
# Comp:  2            [OI]6300_d      2.741       1.7     -54   110
# Comp:  2           [NII]6583_d      2.026       1.7     -54   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -191       390
#  comp.  1:       -38        64
#  comp.  2:       -66         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.019       1.1     -38    64
# Comp:  1                Halpha      6.983       1.1     -38    64
# Comp:  2             [SII]6716      1.252      0.97     -66     1
# Comp:  2             [SII]6731      2.335      0.97     -66     1
# Comp:  2              HeII4687      1.168      0.97     -66     1
# Comp:  2               HeI5876     0.7771      0.97     -66     1
# Comp:  2          [OIII]5007_d      1.283       1.2     -66     1
# Comp:  2            [OI]6300_d      2.698       1.2     -66     1
# Comp:  2           [NII]6583_d      1.801       1.2     -66     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -369       270
#  comp.  1:       -50        91
#  comp.  2:       -46        16
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.699       1.3     -50    91
# Comp:  1                Halpha      7.067       1.3     -50    91
# Comp:  2             [SII]6716      1.626      0.99     -46    16
# Comp:  2             [SII]6731      2.486      0.99     -46    16
# Comp:  2              HeII4687      1.653      0.99     -46    16
# Comp:  2               HeI5876     0.9530      0.99     -46    16
# Comp:  2          [OIII]5007_d      1.555       1.2     -46    16
# Comp:  2            [OI]6300_d      1.611       1.2     -46    16
# Comp:  2           [NII]6583_d      3.428       1.2     -46    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63       336
#  comp.  1:       -43        37
#  comp.  2:       -65        65
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.032       1.0     -43    37
# Comp:  1                Halpha      5.386       1.0     -43    37
# Comp:  2             [SII]6716      1.752       1.2     -65    65
# Comp:  2             [SII]6731      2.283       1.2     -65    65
# Comp:  2              HeII4687      0.000       1.2     -65    65
# Comp:  2               HeI5876     0.6519       1.2     -65    65
# Comp:  2          [OIII]5007_d     0.8102       1.5     -65    65
# Comp:  2            [OI]6300_d      1.775       1.5     -65    65
# Comp:  2           [NII]6583_d      2.227       1.5     -65    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -250       146
#  comp.  1:       -48        67
#  comp.  2:       -65        53
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.787       1.2     -48    67
# Comp:  1                Halpha      7.759       1.2     -48    67
# Comp:  2             [SII]6716     0.7533       1.1     -65    53
# Comp:  2             [SII]6731      2.225       1.1     -65    53
# Comp:  2              HeII4687      2.608       1.1     -65    53
# Comp:  2               HeI5876     0.8800       1.1     -65    53
# Comp:  2          [OIII]5007_d      1.616       1.4     -65    53
# Comp:  2            [OI]6300_d      2.414       1.4     -65    53
# Comp:  2           [NII]6583_d      2.372       1.4     -65    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56       101
#  comp.  1:       -40        52
#  comp.  2:       -53         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.238       1.1     -40    52
# Comp:  1                Halpha      7.336       1.1     -40    52
# Comp:  2             [SII]6716      1.014      0.97     -53     1
# Comp:  2             [SII]6731      2.130      0.97     -53     1
# Comp:  2              HeII4687     0.5555      0.97     -53     1
# Comp:  2               HeI5876     0.2182      0.97     -53     1
# Comp:  2          [OIII]5007_d      1.616       1.2     -53     1
# Comp:  2            [OI]6300_d      1.861       1.2     -53     1
# Comp:  2           [NII]6583_d      2.329       1.2     -53     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36       402
#  comp.  1:       -44        70
#  comp.  2:       -49         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.165       1.2     -44    70
# Comp:  1                Halpha      5.937       1.2     -44    70
# Comp:  2             [SII]6716      1.625      0.97     -49     1
# Comp:  2             [SII]6731      2.347      0.97     -49     1
# Comp:  2              HeII4687      1.683      0.97     -49     1
# Comp:  2               HeI5876     0.8200      0.97     -49     1
# Comp:  2          [OIII]5007_d      1.850       1.2     -49     1
# Comp:  2            [OI]6300_d      1.830       1.2     -49     1
# Comp:  2           [NII]6583_d      1.589       1.2     -49     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85       262
#  comp.  1:       -43        67
#  comp.  2:       -60        51
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.252       1.2     -43    67
# Comp:  1                Halpha      6.616       1.2     -43    67
# Comp:  2             [SII]6716     0.6001       1.1     -60    51
# Comp:  2             [SII]6731      2.622       1.1     -60    51
# Comp:  2              HeII4687      2.196       1.1     -60    51
# Comp:  2               HeI5876     0.4023       1.1     -60    51
# Comp:  2          [OIII]5007_d      2.204       1.4     -60    51
# Comp:  2            [OI]6300_d      2.169       1.4     -60    51
# Comp:  2           [NII]6583_d      2.020       1.4     -60    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71       273
#  comp.  1:       -42        65
#  comp.  2:       -58        29
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.972       1.2     -42    65
# Comp:  1                Halpha      6.739       1.2     -42    65
# Comp:  2             [SII]6716      1.227       1.0     -58    29
# Comp:  2             [SII]6731      2.149       1.0     -58    29
# Comp:  2              HeII4687      2.089       1.0     -58    29
# Comp:  2               HeI5876     0.5500       1.0     -58    29
# Comp:  2          [OIII]5007_d      1.506       1.3     -58    29
# Comp:  2            [OI]6300_d      1.632       1.3     -58    29
# Comp:  2           [NII]6583_d      2.553       1.3     -58    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -342         1
#  comp.  1:       -36        60
#  comp.  2:       -53         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.258       1.1     -36    60
# Comp:  1                Halpha      5.839       1.1     -36    60
# Comp:  2             [SII]6716      1.813      0.97     -53     1
# Comp:  2             [SII]6731      2.629      0.97     -53     1
# Comp:  2              HeII4687      1.465      0.97     -53     1
# Comp:  2               HeI5876     0.5065      0.97     -53     1
# Comp:  2          [OIII]5007_d     0.9800       1.2     -53     1
# Comp:  2            [OI]6300_d      2.458       1.2     -53     1
# Comp:  2           [NII]6583_d      2.259       1.2     -53     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -614      1000
#  comp.  1:       -59        46
#  comp.  2:       -58         1
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.166       1.1     -59    46
# Comp:  1                Halpha      6.508       1.1     -59    46
# Comp:  2             [SII]6716      1.115      0.97     -58     1
# Comp:  2             [SII]6731      2.460      0.97     -58     1
# Comp:  2              HeII4687     0.5695      0.97     -58     1
# Comp:  2               HeI5876     0.9815      0.97     -58     1
# Comp:  2          [OIII]5007_d      1.085       1.2     -58     1
# Comp:  2            [OI]6300_d      1.889       1.2     -58     1
# Comp:  2           [NII]6583_d      2.303       1.2     -58     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77       252
#  comp.  1:       -40        67
#  comp.  2:       -54        41
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9724       1.2     -40    67
# Comp:  1                Halpha      5.924       1.2     -40    67
# Comp:  2             [SII]6716      1.143       1.1     -54    41
# Comp:  2             [SII]6731      3.011       1.1     -54    41
# Comp:  2              HeII4687      1.652       1.1     -54    41
# Comp:  2               HeI5876     0.4165       1.1     -54    41
# Comp:  2          [OIII]5007_d      1.482       1.3     -54    41
# Comp:  2            [OI]6300_d      1.660       1.3     -54    41
# Comp:  2           [NII]6583_d      2.768       1.3     -54    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       429       644
#  comp.  1:       -27        53
#  comp.  2:       -61         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1614       1.1     -27    53
# Comp:  1                Halpha      6.457       1.1     -27    53
# Comp:  2             [SII]6716      1.050      0.97     -61     1
# Comp:  2             [SII]6731      2.004      0.97     -61     1
# Comp:  2              HeII4687     0.9858      0.97     -61     1
# Comp:  2               HeI5876     0.3773      0.97     -61     1
# Comp:  2          [OIII]5007_d     0.7276       1.2     -61     1
# Comp:  2            [OI]6300_d      1.302       1.2     -61     1
# Comp:  2           [NII]6583_d      3.297       1.2     -61     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       147       236
#  comp.  1:       -61        52
#  comp.  2:       -60        57
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7707       1.1     -61    52
# Comp:  1                Halpha      6.269       1.1     -61    52
# Comp:  2             [SII]6716      1.560       1.1     -60    57
# Comp:  2             [SII]6731      2.938       1.1     -60    57
# Comp:  2              HeII4687      1.930       1.1     -60    57
# Comp:  2               HeI5876     0.5822       1.1     -60    57
# Comp:  2          [OIII]5007_d     0.2211       1.4     -60    57
# Comp:  2            [OI]6300_d      1.722       1.4     -60    57
# Comp:  2           [NII]6583_d      1.970       1.4     -60    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45       513
#  comp.  1:       -53        67
#  comp.  2:       -86         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.712       1.2     -53    67
# Comp:  1                Halpha      6.789       1.2     -53    67
# Comp:  2             [SII]6716     0.6978      0.97     -86     1
# Comp:  2             [SII]6731      1.974      0.97     -86     1
# Comp:  2              HeII4687      1.234      0.97     -86     1
# Comp:  2               HeI5876     0.6318      0.97     -86     1
# Comp:  2          [OIII]5007_d     0.7834       1.2     -86     1
# Comp:  2            [OI]6300_d      1.641       1.2     -86     1
# Comp:  2           [NII]6583_d      1.737       1.2     -86     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20       381
#  comp.  1:       -55        61
#  comp.  2:       -72        39
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.609       1.1     -55    61
# Comp:  1                Halpha      6.772       1.1     -55    61
# Comp:  2             [SII]6716     0.9621       1.0     -72    39
# Comp:  2             [SII]6731      2.249       1.0     -72    39
# Comp:  2              HeII4687      1.383       1.0     -72    39
# Comp:  2               HeI5876     0.5040       1.0     -72    39
# Comp:  2          [OIII]5007_d     0.9597       1.3     -72    39
# Comp:  2            [OI]6300_d      1.933       1.3     -72    39
# Comp:  2           [NII]6583_d      1.782       1.3     -72    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -172       223
#  comp.  1:       -28        65
#  comp.  2:       -49         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.192       1.2     -28    65
# Comp:  1                Halpha      6.452       1.2     -28    65
# Comp:  2             [SII]6716      1.395      0.97     -49     1
# Comp:  2             [SII]6731      1.971      0.97     -49     1
# Comp:  2              HeII4687      1.515      0.97     -49     1
# Comp:  2               HeI5876     0.9224      0.97     -49     1
# Comp:  2          [OIII]5007_d     0.6836       1.2     -49     1
# Comp:  2            [OI]6300_d      1.472       1.2     -49     1
# Comp:  2           [NII]6583_d      1.741       1.2     -49     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       229
#  comp.  1:       -51        44
#  comp.  2:       -64        27
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.844       1.1     -51    44
# Comp:  1                Halpha      6.804       1.1     -51    44
# Comp:  2             [SII]6716      1.909       1.0     -64    27
# Comp:  2             [SII]6731      2.482       1.0     -64    27
# Comp:  2              HeII4687      2.601       1.0     -64    27
# Comp:  2               HeI5876     0.5751       1.0     -64    27
# Comp:  2          [OIII]5007_d      1.420       1.3     -64    27
# Comp:  2            [OI]6300_d      1.820       1.3     -64    27
# Comp:  2           [NII]6583_d      2.719       1.3     -64    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101       374
#  comp.  1:       -54        67
#  comp.  2:       -56        81
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.668       1.2     -54    67
# Comp:  1                Halpha      7.213       1.2     -54    67
# Comp:  2             [SII]6716     0.6605       1.2     -56    81
# Comp:  2             [SII]6731      3.027       1.2     -56    81
# Comp:  2              HeII4687      3.482       1.2     -56    81
# Comp:  2               HeI5876      1.117       1.2     -56    81
# Comp:  2          [OIII]5007_d      2.149       1.5     -56    81
# Comp:  2            [OI]6300_d      3.561       1.5     -56    81
# Comp:  2           [NII]6583_d      3.528       1.5     -56    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48       127
#  comp.  1:       -30        39
#  comp.  2:       -66         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.635       1.0     -30    39
# Comp:  1                Halpha      5.861       1.0     -30    39
# Comp:  2             [SII]6716      1.002      0.97     -66     1
# Comp:  2             [SII]6731      2.016      0.97     -66     1
# Comp:  2              HeII4687      1.579      0.97     -66     1
# Comp:  2               HeI5876     0.2487      0.97     -66     1
# Comp:  2          [OIII]5007_d      2.259       1.2     -66     1
# Comp:  2            [OI]6300_d      1.452       1.2     -66     1
# Comp:  2           [NII]6583_d      1.585       1.2     -66     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -239       145
#  comp.  1:       -34        57
#  comp.  2:       -97        46
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.906       1.1     -34    57
# Comp:  1                Halpha      5.601       1.1     -34    57
# Comp:  2             [SII]6716      1.761       1.1     -97    46
# Comp:  2             [SII]6731      2.267       1.1     -97    46
# Comp:  2              HeII4687      1.588       1.1     -97    46
# Comp:  2               HeI5876     0.6839       1.1     -97    46
# Comp:  2          [OIII]5007_d      1.676       1.4     -97    46
# Comp:  2            [OI]6300_d      2.540       1.4     -97    46
# Comp:  2           [NII]6583_d      2.422       1.4     -97    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        66
#  comp.  1:       -59        74
#  comp.  2:       -61         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.271       1.2     -59    74
# Comp:  1                Halpha      8.296       1.2     -59    74
# Comp:  2             [SII]6716      1.676      0.97     -61     1
# Comp:  2             [SII]6731      2.295      0.97     -61     1
# Comp:  2              HeII4687     0.8929      0.97     -61     1
# Comp:  2               HeI5876     0.9320      0.97     -61     1
# Comp:  2          [OIII]5007_d     0.8836       1.2     -61     1
# Comp:  2            [OI]6300_d      2.480       1.2     -61     1
# Comp:  2           [NII]6583_d      2.450       1.2     -61     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33       360
#  comp.  1:       -51        55
#  comp.  2:       -40         1
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9440       1.1     -51    55
# Comp:  1                Halpha      6.445       1.1     -51    55
# Comp:  2             [SII]6716     0.7774      0.97     -40     1
# Comp:  2             [SII]6731      2.729      0.97     -40     1
# Comp:  2              HeII4687      2.116      0.97     -40     1
# Comp:  2               HeI5876     0.7814      0.97     -40     1
# Comp:  2          [OIII]5007_d     0.9941       1.2     -40     1
# Comp:  2            [OI]6300_d      1.837       1.2     -40     1
# Comp:  2           [NII]6583_d      2.610       1.2     -40     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108       161
#  comp.  1:       -61        60
#  comp.  2:       -68         1
# chi2/DOF: 1.119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.440       1.1     -61    60
# Comp:  1                Halpha      7.672       1.1     -61    60
# Comp:  2             [SII]6716      1.161      0.97     -68     1
# Comp:  2             [SII]6731      2.173      0.97     -68     1
# Comp:  2              HeII4687      1.426      0.97     -68     1
# Comp:  2               HeI5876     0.3488      0.97     -68     1
# Comp:  2          [OIII]5007_d      1.147       1.2     -68     1
# Comp:  2            [OI]6300_d      2.256       1.2     -68     1
# Comp:  2           [NII]6583_d      2.494       1.2     -68     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -389       536
#  comp.  1:       -44        64
#  comp.  2:       -45         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.068       1.1     -44    64
# Comp:  1                Halpha      6.450       1.1     -44    64
# Comp:  2             [SII]6716     0.5314      0.97     -45     1
# Comp:  2             [SII]6731      2.192      0.97     -45     1
# Comp:  2              HeII4687      2.062      0.97     -45     1
# Comp:  2               HeI5876     0.6175      0.97     -45     1
# Comp:  2          [OIII]5007_d      1.480       1.2     -45     1
# Comp:  2            [OI]6300_d      2.127       1.2     -45     1
# Comp:  2           [NII]6583_d      3.360       1.2     -45     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113        88
#  comp.  1:       -38        53
#  comp.  2:       -42        91
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.587       1.1     -38    53
# Comp:  1                Halpha      7.420       1.1     -38    53
# Comp:  2             [SII]6716     0.6538       1.3     -42    91
# Comp:  2             [SII]6731      3.687       1.3     -42    91
# Comp:  2              HeII4687      2.283       1.3     -42    91
# Comp:  2               HeI5876     0.2341       1.3     -42    91
# Comp:  2          [OIII]5007_d      1.079       1.6     -42    91
# Comp:  2            [OI]6300_d     0.9424       1.6     -42    91
# Comp:  2           [NII]6583_d      1.991       1.6     -42    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       171       824
#  comp.  1:       -59        70
#  comp.  2:       -54         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.716       1.2     -59    70
# Comp:  1                Halpha      6.770       1.2     -59    70
# Comp:  2             [SII]6716     0.8796      0.97     -54     1
# Comp:  2             [SII]6731      2.456      0.97     -54     1
# Comp:  2              HeII4687     0.4098      0.97     -54     1
# Comp:  2               HeI5876     0.9106      0.97     -54     1
# Comp:  2          [OIII]5007_d      1.039       1.2     -54     1
# Comp:  2            [OI]6300_d      1.285       1.2     -54     1
# Comp:  2           [NII]6583_d      2.616       1.2     -54     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       273
#  comp.  1:       -42        63
#  comp.  2:       -57        31
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.718       1.1     -42    63
# Comp:  1                Halpha      7.998       1.1     -42    63
# Comp:  2             [SII]6716     0.9866       1.0     -57    31
# Comp:  2             [SII]6731      2.391       1.0     -57    31
# Comp:  2              HeII4687      1.499       1.0     -57    31
# Comp:  2               HeI5876     0.8604       1.0     -57    31
# Comp:  2          [OIII]5007_d      2.303       1.3     -57    31
# Comp:  2            [OI]6300_d      2.215       1.3     -57    31
# Comp:  2           [NII]6583_d      3.017       1.3     -57    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77       274
#  comp.  1:       -41        62
#  comp.  2:       -58        62
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.496       1.1     -41    62
# Comp:  1                Halpha      6.700       1.1     -41    62
# Comp:  2             [SII]6716      1.214       1.1     -58    62
# Comp:  2             [SII]6731      2.703       1.1     -58    62
# Comp:  2              HeII4687     0.7110       1.1     -58    62
# Comp:  2               HeI5876     0.9987       1.1     -58    62
# Comp:  2          [OIII]5007_d      1.921       1.4     -58    62
# Comp:  2            [OI]6300_d      1.425       1.4     -58    62
# Comp:  2           [NII]6583_d      2.221       1.4     -58    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       373
#  comp.  1:       -34        50
#  comp.  2:       -48        34
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.754       1.1     -34    50
# Comp:  1                Halpha      6.972       1.1     -34    50
# Comp:  2             [SII]6716      1.038       1.0     -48    34
# Comp:  2             [SII]6731      2.918       1.0     -48    34
# Comp:  2              HeII4687     0.6452       1.0     -48    34
# Comp:  2               HeI5876     0.6408       1.0     -48    34
# Comp:  2          [OIII]5007_d      1.994       1.3     -48    34
# Comp:  2            [OI]6300_d      2.531       1.3     -48    34
# Comp:  2           [NII]6583_d      2.050       1.3     -48    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -198       440
#  comp.  1:       -31        49
#  comp.  2:       -48         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.297       1.1     -31    49
# Comp:  1                Halpha      5.634       1.1     -31    49
# Comp:  2             [SII]6716      1.149      0.97     -48     1
# Comp:  2             [SII]6731      2.541      0.97     -48     1
# Comp:  2              HeII4687      2.056      0.97     -48     1
# Comp:  2               HeI5876     0.6704      0.97     -48     1
# Comp:  2          [OIII]5007_d     0.9205       1.2     -48     1
# Comp:  2            [OI]6300_d      1.366       1.2     -48     1
# Comp:  2           [NII]6583_d      1.356       1.2     -48     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -196       294
#  comp.  1:       -34        42
#  comp.  2:       -61         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.032       1.1     -34    42
# Comp:  1                Halpha      5.049       1.1     -34    42
# Comp:  2             [SII]6716      1.288      0.97     -61     1
# Comp:  2             [SII]6731      2.501      0.97     -61     1
# Comp:  2              HeII4687      1.305      0.97     -61     1
# Comp:  2               HeI5876     0.5029      0.97     -61     1
# Comp:  2          [OIII]5007_d      1.919       1.2     -61     1
# Comp:  2            [OI]6300_d      2.065       1.2     -61     1
# Comp:  2           [NII]6583_d      1.483       1.2     -61     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28       439
#  comp.  1:       -27        70
#  comp.  2:       -51         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.739       1.2     -27    70
# Comp:  1                Halpha      6.617       1.2     -27    70
# Comp:  2             [SII]6716      1.163      0.97     -51     1
# Comp:  2             [SII]6731      1.938      0.97     -51     1
# Comp:  2              HeII4687      1.970      0.97     -51     1
# Comp:  2               HeI5876     0.5288      0.97     -51     1
# Comp:  2          [OIII]5007_d     0.4198       1.2     -51     1
# Comp:  2            [OI]6300_d      2.405       1.2     -51     1
# Comp:  2           [NII]6583_d      2.064       1.2     -51     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       190
#  comp.  1:       -50        27
#  comp.  2:       -39        29
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.735       1.0     -50    27
# Comp:  1                Halpha      6.545       1.0     -50    27
# Comp:  2             [SII]6716     0.7257       1.0     -39    29
# Comp:  2             [SII]6731      2.782       1.0     -39    29
# Comp:  2              HeII4687      1.604       1.0     -39    29
# Comp:  2               HeI5876     0.5947       1.0     -39    29
# Comp:  2          [OIII]5007_d      1.752       1.3     -39    29
# Comp:  2            [OI]6300_d      2.119       1.3     -39    29
# Comp:  2           [NII]6583_d      1.004       1.3     -39    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -181       313
#  comp.  1:       -51        57
#  comp.  2:       -47         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.961       1.1     -51    57
# Comp:  1                Halpha      6.006       1.1     -51    57
# Comp:  2             [SII]6716      1.491      0.97     -47     1
# Comp:  2             [SII]6731      2.618      0.97     -47     1
# Comp:  2              HeII4687      1.778      0.97     -47     1
# Comp:  2               HeI5876     0.5131      0.97     -47     1
# Comp:  2          [OIII]5007_d      1.492       1.2     -47     1
# Comp:  2            [OI]6300_d     0.9354       1.2     -47     1
# Comp:  2           [NII]6583_d      2.412       1.2     -47     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        98
#  comp.  1:       -36        67
#  comp.  2:       -81        57
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.448       1.2     -36    67
# Comp:  1                Halpha      5.951       1.2     -36    67
# Comp:  2             [SII]6716      1.114       1.1     -81    57
# Comp:  2             [SII]6731      2.594       1.1     -81    57
# Comp:  2              HeII4687      2.194       1.1     -81    57
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7034       1.1     -56    42
# Comp:  1                Halpha      5.007       1.1     -56    42
# Comp:  2             [SII]6716     0.5030       1.0     -94    37
# Comp:  2             [SII]6731      2.279       1.0     -94    37
# Comp:  2              HeII4687      2.136       1.0     -94    37
# Comp:  2               HeI5876     0.6832       1.0     -94    37
# Comp:  2          [OIII]5007_d      0.000       1.3     -94    37
# Comp:  2            [OI]6300_d      1.727       1.3     -94    37
# Comp:  2           [NII]6583_d      2.269       1.3     -94    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       407       443
#  comp.  1:       -41        71
#  comp.  2:       -41         1
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.552       1.2     -41    71
# Comp:  1                Halpha      6.932       1.2     -41    71
# Comp:  2             [SII]6716      1.003      0.97     -41     1
# Comp:  2             [SII]6731      2.295      0.97     -41     1
# Comp:  2              HeII4687      1.697      0.97     -41     1
# Comp:  2               HeI5876     0.2631      0.97     -41     1
# Comp:  2          [OIII]5007_d      1.347       1.2     -41     1
# Comp:  2            [OI]6300_d      2.158       1.2     -41     1
# Comp:  2           [NII]6583_d      2.573       1.2     -41     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19       329
#  comp.  1:       -23        65
#  comp.  2:       -62        22
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.886       1.2     -23    65
# Comp:  1                Halpha      7.951       1.2     -23    65
# Comp:  2             [SII]6716     0.9595       1.0     -62    22
# Comp:  2             [SII]6731      2.048       1.0     -62    22
# Comp:  2              HeII4687      2.035       1.0     -62    22
# Comp:  2               HeI5876     0.7439       1.0     -62    22
# Comp:  2          [OIII]5007_d      1.725       1.3     -62    22
# Comp:  2            [OI]6300_d      2.434       1.3     -62    22
# Comp:  2           [NII]6583_d      1.551       1.3     -62    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       425
#  comp.  1:       -28        69
#  comp.  2:       -67        82
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.085       1.2     -28    69
# Comp:  1                Halpha      7.345       1.2     -28    69
# Comp:  2             [SII]6716      1.952       1.2     -67    82
# Comp:  2             [SII]6731      2.983       1.2     -67    82
# Comp:  2              HeII4687      3.231       1.2     -67    82
# Comp:  2               HeI5876      1.340       1.2     -67    82
# Comp:  2          [OIII]5007_d      2.849       1.6     -67    82
# Comp:  2            [OI]6300_d     0.7462       1.6     -67    82
# Comp:  2           [NII]6583_d      2.579       1.6     -67    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140       181
#  comp.  1:       -56        78
#  comp.  2:       -60        73
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.599       1.2     -56    78
# Comp:  1                Halpha      6.358       1.2     -56    78
# Comp:  2             [SII]6716      1.786       1.2     -60    73
# Comp:  2             [SII]6731      2.356       1.2     -60    73
# Comp:  2              HeII4687      1.389       1.2     -60    73
# Comp:  2               HeI5876     0.6553       1.2     -60    73
# Comp:  2          [OIII]5007_d      1.491       1.5     -60    73
# Comp:  2            [OI]6300_d      3.420       1.5     -60    73
# Comp:  2           [NII]6583_d      2.678       1.5     -60    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -117       336
#  comp.  1:       -60        61
#  comp.  2:       -36        13
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.818       1.1     -60    61
# Comp:  1                Halpha      6.530       1.1     -60    61
# Comp:  2             [SII]6716      1.121      0.98     -36    13
# Comp:  2             [SII]6731      2.361      0.98     -36    13
# Comp:  2              HeII4687      1.971      0.98     -36    13
# Comp:  2               HeI5876      1.052      0.98     -36    13
# Comp:  2          [OIII]5007_d      1.300       1.2     -36    13
# Comp:  2            [OI]6300_d      1.885       1.2     -36    13
# Comp:  2           [NII]6583_d      2.427       1.2     -36    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101       146
#  comp.  1:       -54        53
#  comp.  2:       -37         1
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.980       1.1     -54    53
# Comp:  1                Halpha      7.151       1.1     -54    53
# Comp:  2             [SII]6716      1.170      0.97     -37     1
# Comp:  2             [SII]6731      2.490      0.97     -37     1
# Comp:  2              HeII4687      1.921      0.97     -37     1
# Comp:  2               HeI5876     0.4249      0.97     -37     1
# Comp:  2          [OIII]5007_d      1.524       1.2     -37     1
# Comp:  2            [OI]6300_d      1.510       1.2     -37     1
# Comp:  2           [NII]6583_d      2.539       1.2     -37     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -263       103
#  comp.  1:       -51        43
#  comp.  2:       -93        44
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.257       1.1     -51    43
# Comp:  1                Halpha      6.225       1.1     -51    43
# Comp:  2             [SII]6716      1.343       1.1     -93    44
# Comp:  2             [SII]6731      2.053       1.1     -93    44
# Comp:  2              HeII4687      1.674       1.1     -93    44
# Comp:  2               HeI5876     0.7117       1.1     -93    44
# Comp:  2          [OIII]5007_d      1.249       1.3     -93    44
# Comp:  2            [OI]6300_d      1.923       1.3     -93    44
# Comp:  2           [NII]6583_d      2.468       1.3     -93    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -189        26
#  comp.  1:       -52        84
#  comp.  2:       -36         1
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.530       1.2     -52    84
# Comp:  1                Halpha      6.816       1.2     -52    84
# Comp:  2             [SII]6716      1.044      0.97     -36     1
# Comp:  2             [SII]6731      2.087      0.97     -36     1
# Comp:  2              HeII4687      1.770      0.97     -36     1
# Comp:  2               HeI5876     0.4685      0.97     -36     1
# Comp:  2          [OIII]5007_d      1.112       1.2     -36     1
# Comp:  2            [OI]6300_d      1.687       1.2     -36     1
# Comp:  2           [NII]6583_d      2.768       1.2     -36     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88       223
#  comp.  1:       -64        69
#  comp.  2:       -39         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.103       1.2     -64    69
# Comp:  1                Halpha      5.939       1.2     -64    69
# Comp:  2             [SII]6716     0.9051      0.97     -39     1
# Comp:  2             [SII]6731      2.297      0.97     -39     1
# Comp:  2              HeII4687      1.727      0.97     -39     1
# Comp:  2               HeI5876     0.6103      0.97     -39     1
# Comp:  2          [OIII]5007_d     0.8647       1.2     -39     1
# Comp:  2            [OI]6300_d      2.438       1.2     -39     1
# Comp:  2           [NII]6583_d      1.780       1.2     -39     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -195       282
#  comp.  1:       -69        46
#  comp.  2:       -57        81
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.387       1.1     -69    46
# Comp:  1                Halpha      6.116       1.1     -69    46
# Comp:  2             [SII]6716      2.189       1.2     -57    81
# Comp:  2             [SII]6731      3.439       1.2     -57    81
# Comp:  2              HeII4687      3.232       1.2     -57    81
# Comp:  2               HeI5876      1.214       1.2     -57    81
# Comp:  2          [OIII]5007_d      1.503       1.5     -57    81
# Comp:  2            [OI]6300_d      2.658       1.5     -57    81
# Comp:  2           [NII]6583_d      3.410       1.5     -57    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113         1
#  comp.  1:       -35        67
#  comp.  2:       -45         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.919       1.2     -35    67
# Comp:  1                Halpha      8.049       1.2     -35    67
# Comp:  2             [SII]6716      1.156      0.97     -45     1
# Comp:  2             [SII]6731      2.519      0.97     -45     1
# Comp:  2              HeII4687      1.544      0.97     -45     1
# Comp:  2               HeI5876     0.6992      0.97     -45     1
# Comp:  2          [OIII]5007_d      1.929       1.2     -45     1
# Comp:  2            [OI]6300_d      2.434       1.2     -45     1
# Comp:  2           [NII]6583_d      2.573       1.2     -45     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       157       285
#  comp.  1:       -26        45
#  comp.  2:       -36         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.567       1.1     -26    45
# Comp:  1                Halpha      6.093       1.1     -26    45
# Comp:  2             [SII]6716     0.9506      0.97     -36     1
# Comp:  2             [SII]6731      2.680      0.97     -36     1
# Comp:  2              HeII4687      2.075      0.97     -36     1
# Comp:  2               HeI5876     0.7772      0.97     -36     1
# Comp:  2          [OIII]5007_d      1.271       1.2     -36     1
# Comp:  2            [OI]6300_d      2.596       1.2     -36     1
# Comp:  2           [NII]6583_d      3.077       1.2     -36     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       146       290
#  comp.  1:       -45        64
#  comp.  2:       -40        27
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.913       1.2     -45    64
# Comp:  1                Halpha      7.222       1.2     -45    64
# Comp:  2             [SII]6716      1.617       1.0     -40    27
# Comp:  2             [SII]6731      2.457       1.0     -40    27
# Comp:  2              HeII4687      1.797       1.0     -40    27
# Comp:  2               HeI5876     0.8153       1.0     -40    27
# Comp:  2          [OIII]5007_d      1.882       1.3     -40    27
# Comp:  2            [OI]6300_d      2.791       1.3     -40    27
# Comp:  2           [NII]6583_d      2.785       1.3     -40    27
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.99320104, 1.2269194 , 0.65580427, 1.22980206, 1.26165254,
#        1.07389272, 0.94633886, 1.56899586, 1.31190604])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([2.03818566, 9.37226916, 1.53035891, 3.19379917, 1.3567141 ,
#        0.77504892, 1.31043917, 2.5491775 , 2.907113  ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_15_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_15", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_15_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_15_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_15_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.024359    0.011870
# 1        Halpha  0.112010    0.014663
# 2     [SII]6716  0.018290    0.007838
# 3     [SII]6731  0.038170    0.014698
# 4      HeII4687  0.016214    0.015078
# 5       HeI5876  0.009263    0.012834
# 6  [OIII]5007_d  0.015661    0.011310
# 7    [OI]6300_d  0.030466    0.018751
# 8   [NII]6583_d  0.034744    0.015679
#           Name      Flux  Error_flux
# 0        Hbeta  0.024359    0.011870
# 1       Halpha  0.112010    0.014663
# 2    [SII]6716  0.018290    0.007838
# 3    [SII]6731  0.038170    0.014698
# 4     HeII4687  0.016214    0.015078
# 5      HeI5876  0.009263    0.012834
# 6   [OIII]4959  0.003915    0.011310
# 7   [OIII]5007  0.011746    0.011310
# 8     [OI]6300  0.022849    0.018751
# 9     [OI]6364  0.007616    0.018751
# 10   [NII]6548  0.008686    0.015679
# 11   [NII]6583  0.026058    0.015679

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01195120622108144
