# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = 0.00189 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4444.779367   4446.25657507 4447.73378315 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.06122928 0.05022774 0.04848297 ... 0.03438179 0.03616753 0.03608271] [0.00801512 0.00801512 0.00801512 ... 0.00801512 0.00801512 0.00801512]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
# chi2/DOF: 0.03610; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
# chi2/DOF: 0.01444; DOF: 1907; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-48.12313636,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        41
#  comp.  1:       -52        58
#  comp.  2:       -64        48
# chi2/DOF: 0.9067; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.939      0.43     -52    58
# Comp:  1                Halpha      18.50      0.43     -52    58
# Comp:  2             [SII]6716      4.637      0.42     -64    48
# Comp:  2             [SII]6731      3.360      0.42     -64    48
# Comp:  2              HeII4687      0.000      0.42     -64    48
# Comp:  2               HeI5876      0.000      0.42     -64    48
# Comp:  2          [OIII]5007_d      4.412      0.53     -64    48
# Comp:  2            [OI]6300_d      1.565      0.53     -64    48
# Comp:  2           [NII]6583_d      3.592      0.53     -64    48
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  13.38; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  41.29; gas flux:     25 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  10.57; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  8.053; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  7.994; gas flux:      5 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.846; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  6.332; gas flux:      5 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         9       107
#  comp.  1:       -52        58
#  comp.  2:       -61        55
# chi2/DOF: 0.8996; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.670      0.43     -52    58
# Comp:  1                Halpha      18.62      0.43     -52    58
# Comp:  2             [SII]6716      4.755      0.43     -61    55
# Comp:  2             [SII]6731      3.466      0.43     -61    55
# Comp:  2              HeII4687    0.03622      0.43     -61    55
# Comp:  2               HeI5876     0.1038      0.43     -61    55
# Comp:  2          [OIII]5007_d      5.062      0.54     -61    55
# Comp:  2            [OI]6300_d     0.9042      0.54     -61    55
# Comp:  2           [NII]6583_d      3.429      0.54     -61    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -48        55
#  comp.  2:       -62        44
# chi2/DOF: 0.9019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.701      0.43     -48    55
# Comp:  1                Halpha      18.62      0.43     -48    55
# Comp:  2             [SII]6716      4.581      0.41     -62    44
# Comp:  2             [SII]6731      3.352      0.41     -62    44
# Comp:  2              HeII4687     0.4940      0.41     -62    44
# Comp:  2               HeI5876     0.1150      0.41     -62    44
# Comp:  2          [OIII]5007_d      4.069      0.52     -62    44
# Comp:  2            [OI]6300_d      1.529      0.52     -62    44
# Comp:  2           [NII]6583_d      3.356      0.52     -62    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        51
#  comp.  1:       -52        59
#  comp.  2:       -72        47
# chi2/DOF: 0.9022; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.809      0.43     -52    59
# Comp:  1                Halpha      18.71      0.43     -52    59
# Comp:  2             [SII]6716      4.560      0.42     -72    47
# Comp:  2             [SII]6731      3.017      0.42     -72    47
# Comp:  2              HeII4687    0.07551      0.42     -72    47
# Comp:  2               HeI5876      0.000      0.42     -72    47
# Comp:  2          [OIII]5007_d      4.369      0.53     -72    47
# Comp:  2            [OI]6300_d      1.489      0.53     -72    47
# Comp:  2           [NII]6583_d      3.993      0.53     -72    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        36
#  comp.  1:       -52        61
#  comp.  2:       -62        41
# chi2/DOF: 0.8979; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.969      0.44     -52    61
# Comp:  1                Halpha      19.01      0.44     -52    61
# Comp:  2             [SII]6716      4.514      0.41     -62    41
# Comp:  2             [SII]6731      2.948      0.41     -62    41
# Comp:  2              HeII4687     0.2901      0.41     -62    41
# Comp:  2               HeI5876      0.000      0.41     -62    41
# Comp:  2          [OIII]5007_d      4.111      0.51     -62    41
# Comp:  2            [OI]6300_d      1.453      0.51     -62    41
# Comp:  2           [NII]6583_d      3.851      0.51     -62    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        22
#  comp.  1:       -49        61
#  comp.  2:       -59        44
# chi2/DOF: 0.8971; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.388      0.44     -49    61
# Comp:  1                Halpha      19.08      0.44     -49    61
# Comp:  2             [SII]6716      4.443      0.41     -59    44
# Comp:  2             [SII]6731      3.583      0.41     -59    44
# Comp:  2              HeII4687     0.1504      0.41     -59    44
# Comp:  2               HeI5876    0.05807      0.41     -59    44
# Comp:  2          [OIII]5007_d      4.263      0.52     -59    44
# Comp:  2            [OI]6300_d      1.343      0.52     -59    44
# Comp:  2           [NII]6583_d      3.535      0.52     -59    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        53
#  comp.  1:       -51        58
#  comp.  2:       -59        51
# chi2/DOF: 0.8964; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.764      0.43     -51    58
# Comp:  1                Halpha      18.74      0.43     -51    58
# Comp:  2             [SII]6716      4.494      0.42     -59    51
# Comp:  2             [SII]6731      2.989      0.42     -59    51
# Comp:  2              HeII4687      0.000      0.42     -59    51
# Comp:  2               HeI5876     0.1349      0.42     -59    51
# Comp:  2          [OIII]5007_d      4.608      0.53     -59    51
# Comp:  2            [OI]6300_d      1.542      0.53     -59    51
# Comp:  2           [NII]6583_d      3.104      0.53     -59    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        60
#  comp.  1:       -51        62
#  comp.  2:       -59        56
# chi2/DOF: 0.8986; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.964      0.44     -51    62
# Comp:  1                Halpha      19.32      0.44     -51    62
# Comp:  2             [SII]6716      4.757      0.43     -59    56
# Comp:  2             [SII]6731      3.795      0.43     -59    56
# Comp:  2              HeII4687      0.000      0.43     -59    56
# Comp:  2               HeI5876      0.000      0.43     -59    56
# Comp:  2          [OIII]5007_d      4.543      0.54     -59    56
# Comp:  2            [OI]6300_d      1.262      0.54     -59    56
# Comp:  2           [NII]6583_d      3.387      0.54     -59    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        30
#  comp.  1:       -52        56
#  comp.  2:       -60        53
# chi2/DOF: 0.8991; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.542      0.43     -52    56
# Comp:  1                Halpha      18.56      0.43     -52    56
# Comp:  2             [SII]6716      4.604      0.42     -60    53
# Comp:  2             [SII]6731      3.479      0.42     -60    53
# Comp:  2              HeII4687     0.4066      0.42     -60    53
# Comp:  2               HeI5876      0.000      0.42     -60    53
# Comp:  2          [OIII]5007_d      4.298      0.54     -60    53
# Comp:  2            [OI]6300_d      1.166      0.54     -60    53
# Comp:  2           [NII]6583_d      3.316      0.54     -60    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        59
#  comp.  1:       -51        63
#  comp.  2:       -64        46
# chi2/DOF: 0.9017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.892      0.44     -51    63
# Comp:  1                Halpha      19.07      0.44     -51    63
# Comp:  2             [SII]6716      4.583      0.41     -64    46
# Comp:  2             [SII]6731      3.635      0.41     -64    46
# Comp:  2              HeII4687     0.2973      0.41     -64    46
# Comp:  2               HeI5876      0.000      0.41     -64    46
# Comp:  2          [OIII]5007_d      3.935      0.52     -64    46
# Comp:  2            [OI]6300_d      1.380      0.52     -64    46
# Comp:  2           [NII]6583_d      3.828      0.52     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        48
#  comp.  1:       -55        59
#  comp.  2:       -58        43
# chi2/DOF: 0.9011; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.682      0.43     -55    59
# Comp:  1                Halpha      18.35      0.43     -55    59
# Comp:  2             [SII]6716      4.496      0.41     -58    43
# Comp:  2             [SII]6731      2.933      0.41     -58    43
# Comp:  2              HeII4687      0.000      0.41     -58    43
# Comp:  2               HeI5876      0.000      0.41     -58    43
# Comp:  2          [OIII]5007_d      4.401      0.52     -58    43
# Comp:  2            [OI]6300_d      1.427      0.52     -58    43
# Comp:  2           [NII]6583_d      3.087      0.52     -58    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        80
#  comp.  1:       -51        55
#  comp.  2:       -63        45
# chi2/DOF: 0.9027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.212      0.43     -51    55
# Comp:  1                Halpha      18.58      0.43     -51    55
# Comp:  2             [SII]6716      4.618      0.41     -63    45
# Comp:  2             [SII]6731      3.328      0.41     -63    45
# Comp:  2              HeII4687      0.000      0.41     -63    45
# Comp:  2               HeI5876     0.1525      0.41     -63    45
# Comp:  2          [OIII]5007_d      4.437      0.52     -63    45
# Comp:  2            [OI]6300_d      1.827      0.52     -63    45
# Comp:  2           [NII]6583_d      3.674      0.52     -63    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       136
#  comp.  1:       -49        60
#  comp.  2:       -65        55
# chi2/DOF: 0.9016; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.542      0.44     -49    60
# Comp:  1                Halpha      18.97      0.44     -49    60
# Comp:  2             [SII]6716      4.666      0.43     -65    55
# Comp:  2             [SII]6731      3.196      0.43     -65    55
# Comp:  2              HeII4687      0.000      0.43     -65    55
# Comp:  2               HeI5876      0.000      0.43     -65    55
# Comp:  2          [OIII]5007_d      4.262      0.54     -65    55
# Comp:  2            [OI]6300_d      1.400      0.54     -65    55
# Comp:  2           [NII]6583_d      3.500      0.54     -65    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -52        60
#  comp.  2:       -60        60
# chi2/DOF: 0.8945; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.075      0.44     -52    60
# Comp:  1                Halpha      18.74      0.44     -52    60
# Comp:  2             [SII]6716      4.852      0.44     -60    60
# Comp:  2             [SII]6731      3.930      0.44     -60    60
# Comp:  2              HeII4687      0.000      0.44     -60    60
# Comp:  2               HeI5876     0.3173      0.44     -60    60
# Comp:  2          [OIII]5007_d      5.485      0.55     -60    60
# Comp:  2            [OI]6300_d      1.941      0.55     -60    60
# Comp:  2           [NII]6583_d      3.945      0.55     -60    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        52
#  comp.  1:       -53        62
#  comp.  2:       -67        44
# chi2/DOF: 0.8936; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.884      0.44     -53    62
# Comp:  1                Halpha      18.98      0.44     -53    62
# Comp:  2             [SII]6716      4.583      0.41     -67    44
# Comp:  2             [SII]6731      3.337      0.41     -67    44
# Comp:  2              HeII4687      0.000      0.41     -67    44
# Comp:  2               HeI5876      0.000      0.41     -67    44
# Comp:  2          [OIII]5007_d      3.660      0.52     -67    44
# Comp:  2            [OI]6300_d      1.420      0.52     -67    44
# Comp:  2           [NII]6583_d      3.429      0.52     -67    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        26
#  comp.  1:       -53        57
#  comp.  2:       -61        45
# chi2/DOF: 0.8981; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.411      0.43     -53    57
# Comp:  1                Halpha      18.61      0.43     -53    57
# Comp:  2             [SII]6716      4.351      0.41     -61    45
# Comp:  2             [SII]6731      3.241      0.41     -61    45
# Comp:  2              HeII4687   0.008644      0.41     -61    45
# Comp:  2               HeI5876      0.000      0.41     -61    45
# Comp:  2          [OIII]5007_d      4.244      0.52     -61    45
# Comp:  2            [OI]6300_d      2.034      0.52     -61    45
# Comp:  2           [NII]6583_d      3.671      0.52     -61    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        65
#  comp.  1:       -52        62
#  comp.  2:       -67        52
# chi2/DOF: 0.9019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.133      0.44     -52    62
# Comp:  1                Halpha      19.18      0.44     -52    62
# Comp:  2             [SII]6716      4.617      0.42     -67    52
# Comp:  2             [SII]6731      3.492      0.42     -67    52
# Comp:  2              HeII4687    0.03778      0.42     -67    52
# Comp:  2               HeI5876      0.000      0.42     -67    52
# Comp:  2          [OIII]5007_d      5.184      0.53     -67    52
# Comp:  2            [OI]6300_d      1.847      0.53     -67    52
# Comp:  2           [NII]6583_d      3.582      0.53     -67    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        63
#  comp.  1:       -52        58
#  comp.  2:       -60        51
# chi2/DOF: 0.9019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.732      0.43     -52    58
# Comp:  1                Halpha      19.18      0.43     -52    58
# Comp:  2             [SII]6716      4.620      0.42     -60    51
# Comp:  2             [SII]6731      3.027      0.42     -60    51
# Comp:  2              HeII4687     0.2218      0.42     -60    51
# Comp:  2               HeI5876      0.000      0.42     -60    51
# Comp:  2          [OIII]5007_d      4.380      0.53     -60    51
# Comp:  2            [OI]6300_d      1.899      0.53     -60    51
# Comp:  2           [NII]6583_d      3.873      0.53     -60    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -50        59
#  comp.  2:       -63        50
# chi2/DOF: 0.8933; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.112      0.43     -50    59
# Comp:  1                Halpha      18.85      0.43     -50    59
# Comp:  2             [SII]6716      4.635      0.42     -63    50
# Comp:  2             [SII]6731      3.138      0.42     -63    50
# Comp:  2              HeII4687      0.000      0.42     -63    50
# Comp:  2               HeI5876      0.000      0.42     -63    50
# Comp:  2          [OIII]5007_d      4.032      0.53     -63    50
# Comp:  2            [OI]6300_d      1.467      0.53     -63    50
# Comp:  2           [NII]6583_d      3.518      0.53     -63    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        19
#  comp.  1:       -51        60
#  comp.  2:       -59        51
# chi2/DOF: 0.8976; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.761      0.44     -51    60
# Comp:  1                Halpha      18.87      0.44     -51    60
# Comp:  2             [SII]6716      4.600      0.42     -59    51
# Comp:  2             [SII]6731      3.305      0.42     -59    51
# Comp:  2              HeII4687     0.3450      0.42     -59    51
# Comp:  2               HeI5876      0.000      0.42     -59    51
# Comp:  2          [OIII]5007_d      4.286      0.53     -59    51
# Comp:  2            [OI]6300_d      1.114      0.53     -59    51
# Comp:  2           [NII]6583_d      3.464      0.53     -59    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        64
#  comp.  1:       -52        61
#  comp.  2:       -61        58
# chi2/DOF: 0.8994; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.389      0.44     -52    61
# Comp:  1                Halpha      18.58      0.44     -52    61
# Comp:  2             [SII]6716      4.909      0.43     -61    58
# Comp:  2             [SII]6731      3.514      0.43     -61    58
# Comp:  2              HeII4687     0.5097      0.43     -61    58
# Comp:  2               HeI5876      0.000      0.43     -61    58
# Comp:  2          [OIII]5007_d      5.088      0.55     -61    58
# Comp:  2            [OI]6300_d      1.997      0.55     -61    58
# Comp:  2           [NII]6583_d      3.884      0.55     -61    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        41
#  comp.  1:       -49        58
#  comp.  2:       -57        50
# chi2/DOF: 0.8983; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.783      0.43     -49    58
# Comp:  1                Halpha      19.14      0.43     -49    58
# Comp:  2             [SII]6716      4.648      0.42     -57    50
# Comp:  2             [SII]6731      3.398      0.42     -57    50
# Comp:  2              HeII4687      0.000      0.42     -57    50
# Comp:  2               HeI5876     0.1055      0.42     -57    50
# Comp:  2          [OIII]5007_d      4.497      0.53     -57    50
# Comp:  2            [OI]6300_d      1.178      0.53     -57    50
# Comp:  2           [NII]6583_d      3.839      0.53     -57    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        86
#  comp.  1:       -50        56
#  comp.  2:       -65        54
# chi2/DOF: 0.8978; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.988      0.43     -50    56
# Comp:  1                Halpha      18.52      0.43     -50    56
# Comp:  2             [SII]6716      4.745      0.43     -65    54
# Comp:  2             [SII]6731      3.493      0.43     -65    54
# Comp:  2              HeII4687      0.000      0.43     -65    54
# Comp:  2               HeI5876     0.1659      0.43     -65    54
# Comp:  2          [OIII]5007_d      4.885      0.54     -65    54
# Comp:  2            [OI]6300_d      1.482      0.54     -65    54
# Comp:  2           [NII]6583_d      3.877      0.54     -65    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        20
#  comp.  1:       -53        60
#  comp.  2:       -64        38
# chi2/DOF: 0.9015; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.758      0.44     -53    60
# Comp:  1                Halpha      18.59      0.44     -53    60
# Comp:  2             [SII]6716      4.394      0.40     -64    38
# Comp:  2             [SII]6731      2.886      0.40     -64    38
# Comp:  2              HeII4687     0.2355      0.40     -64    38
# Comp:  2               HeI5876      0.000      0.40     -64    38
# Comp:  2          [OIII]5007_d      4.193      0.51     -64    38
# Comp:  2            [OI]6300_d      1.314      0.51     -64    38
# Comp:  2           [NII]6583_d      3.164      0.51     -64    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        37
#  comp.  1:       -51        56
#  comp.  2:       -64        47
# chi2/DOF: 0.9018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.778      0.43     -51    56
# Comp:  1                Halpha      18.57      0.43     -51    56
# Comp:  2             [SII]6716      4.792      0.42     -64    47
# Comp:  2             [SII]6731      3.369      0.42     -64    47
# Comp:  2              HeII4687      0.000      0.42     -64    47
# Comp:  2               HeI5876    0.09967      0.42     -64    47
# Comp:  2          [OIII]5007_d      4.155      0.53     -64    47
# Comp:  2            [OI]6300_d      1.893      0.53     -64    47
# Comp:  2           [NII]6583_d      3.573      0.53     -64    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        26
#  comp.  1:       -52        54
#  comp.  2:       -57        53
# chi2/DOF: 0.9008; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.239      0.43     -52    54
# Comp:  1                Halpha      18.06      0.43     -52    54
# Comp:  2             [SII]6716      4.708      0.42     -57    53
# Comp:  2             [SII]6731      3.740      0.42     -57    53
# Comp:  2              HeII4687      0.000      0.42     -57    53
# Comp:  2               HeI5876     0.1074      0.42     -57    53
# Comp:  2          [OIII]5007_d      4.877      0.54     -57    53
# Comp:  2            [OI]6300_d      1.790      0.54     -57    53
# Comp:  2           [NII]6583_d      3.405      0.54     -57    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        47
#  comp.  1:       -48        58
#  comp.  2:       -70        44
# chi2/DOF: 0.8992; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.014      0.43     -48    58
# Comp:  1                Halpha      18.83      0.43     -48    58
# Comp:  2             [SII]6716      4.668      0.41     -70    44
# Comp:  2             [SII]6731      3.298      0.41     -70    44
# Comp:  2              HeII4687      0.000      0.41     -70    44
# Comp:  2               HeI5876      0.000      0.41     -70    44
# Comp:  2          [OIII]5007_d      3.655      0.52     -70    44
# Comp:  2            [OI]6300_d      1.502      0.52     -70    44
# Comp:  2           [NII]6583_d      3.453      0.52     -70    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        61
#  comp.  1:       -54        58
#  comp.  2:       -64        45
# chi2/DOF: 0.9012; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.863      0.43     -54    58
# Comp:  1                Halpha      18.79      0.43     -54    58
# Comp:  2             [SII]6716      4.595      0.41     -64    45
# Comp:  2             [SII]6731      3.299      0.41     -64    45
# Comp:  2              HeII4687     0.4879      0.41     -64    45
# Comp:  2               HeI5876      0.000      0.41     -64    45
# Comp:  2          [OIII]5007_d      4.239      0.52     -64    45
# Comp:  2            [OI]6300_d      1.287      0.52     -64    45
# Comp:  2           [NII]6583_d      3.650      0.52     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        73
#  comp.  1:       -52        61
#  comp.  2:       -63        59
# chi2/DOF: 0.8948; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.375      0.44     -52    61
# Comp:  1                Halpha      18.83      0.44     -52    61
# Comp:  2             [SII]6716      4.813      0.43     -63    59
# Comp:  2             [SII]6731      3.758      0.43     -63    59
# Comp:  2              HeII4687     0.3054      0.43     -63    59
# Comp:  2               HeI5876    0.09337      0.43     -63    59
# Comp:  2          [OIII]5007_d      4.882      0.55     -63    59
# Comp:  2            [OI]6300_d      2.051      0.55     -63    59
# Comp:  2           [NII]6583_d      4.086      0.55     -63    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        41
#  comp.  1:       -51        58
#  comp.  2:       -68        46
# chi2/DOF: 0.8952; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.772      0.43     -51    58
# Comp:  1                Halpha      18.77      0.43     -51    58
# Comp:  2             [SII]6716      4.398      0.41     -68    46
# Comp:  2             [SII]6731      3.248      0.41     -68    46
# Comp:  2              HeII4687      0.000      0.41     -68    46
# Comp:  2               HeI5876     0.2030      0.41     -68    46
# Comp:  2          [OIII]5007_d      4.487      0.52     -68    46
# Comp:  2            [OI]6300_d      1.677      0.52     -68    46
# Comp:  2           [NII]6583_d      3.273      0.52     -68    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        39
#  comp.  1:       -53        59
#  comp.  2:       -67        30
# chi2/DOF: 0.8986; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.856      0.43     -53    59
# Comp:  1                Halpha      18.39      0.43     -53    59
# Comp:  2             [SII]6716      4.241      0.39     -67    30
# Comp:  2             [SII]6731      2.822      0.39     -67    30
# Comp:  2              HeII4687     0.2893      0.39     -67    30
# Comp:  2               HeI5876     0.1425      0.39     -67    30
# Comp:  2          [OIII]5007_d      3.772      0.50     -67    30
# Comp:  2            [OI]6300_d      1.399      0.50     -67    30
# Comp:  2           [NII]6583_d      2.910      0.50     -67    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        17
#  comp.  1:       -52        57
#  comp.  2:       -57        53
# chi2/DOF: 0.9019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.400      0.43     -52    57
# Comp:  1                Halpha      18.17      0.43     -52    57
# Comp:  2             [SII]6716      4.500      0.42     -57    53
# Comp:  2             [SII]6731      3.744      0.42     -57    53
# Comp:  2              HeII4687      0.000      0.42     -57    53
# Comp:  2               HeI5876    0.04475      0.42     -57    53
# Comp:  2          [OIII]5007_d      4.402      0.54     -57    53
# Comp:  2            [OI]6300_d      1.666      0.54     -57    53
# Comp:  2           [NII]6583_d      3.819      0.54     -57    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        32
#  comp.  1:       -56        57
#  comp.  2:       -58        54
# chi2/DOF: 0.9015; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.316      0.43     -56    57
# Comp:  1                Halpha      18.46      0.43     -56    57
# Comp:  2             [SII]6716      4.797      0.43     -58    54
# Comp:  2             [SII]6731      3.731      0.43     -58    54
# Comp:  2              HeII4687      0.000      0.43     -58    54
# Comp:  2               HeI5876     0.1302      0.43     -58    54
# Comp:  2          [OIII]5007_d      4.440      0.54     -58    54
# Comp:  2            [OI]6300_d      2.110      0.54     -58    54
# Comp:  2           [NII]6583_d      4.143      0.54     -58    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       153       385
#  comp.  1:       -49        57
#  comp.  2:       -68        51
# chi2/DOF: 0.8967; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.570      0.43     -49    57
# Comp:  1                Halpha      18.12      0.43     -49    57
# Comp:  2             [SII]6716      4.498      0.42     -68    51
# Comp:  2             [SII]6731      3.459      0.42     -68    51
# Comp:  2              HeII4687    0.09874      0.42     -68    51
# Comp:  2               HeI5876      0.000      0.42     -68    51
# Comp:  2          [OIII]5007_d      4.800      0.53     -68    51
# Comp:  2            [OI]6300_d      1.671      0.53     -68    51
# Comp:  2           [NII]6583_d      3.368      0.53     -68    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        10
#  comp.  1:       -50        59
#  comp.  2:       -62        55
# chi2/DOF: 0.9008; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.699      0.43     -50    59
# Comp:  1                Halpha      18.73      0.43     -50    59
# Comp:  2             [SII]6716      4.864      0.43     -62    55
# Comp:  2             [SII]6731      3.518      0.43     -62    55
# Comp:  2              HeII4687      0.000      0.43     -62    55
# Comp:  2               HeI5876     0.1750      0.43     -62    55
# Comp:  2          [OIII]5007_d      4.992      0.54     -62    55
# Comp:  2            [OI]6300_d      1.271      0.54     -62    55
# Comp:  2           [NII]6583_d      4.083      0.54     -62    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        39
#  comp.  1:       -54        60
#  comp.  2:       -58        42
# chi2/DOF: 0.8997; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.127      0.44     -54    60
# Comp:  1                Halpha      19.13      0.44     -54    60
# Comp:  2             [SII]6716      4.490      0.41     -58    42
# Comp:  2             [SII]6731      3.206      0.41     -58    42
# Comp:  2              HeII4687     0.2047      0.41     -58    42
# Comp:  2               HeI5876    0.02267      0.41     -58    42
# Comp:  2          [OIII]5007_d      4.008      0.51     -58    42
# Comp:  2            [OI]6300_d      1.682      0.51     -58    42
# Comp:  2           [NII]6583_d      3.751      0.51     -58    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -50        59
#  comp.  2:       -71        45
# chi2/DOF: 0.9010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.864      0.43     -50    59
# Comp:  1                Halpha      18.77      0.43     -50    59
# Comp:  2             [SII]6716      4.526      0.41     -71    45
# Comp:  2             [SII]6731      3.700      0.41     -71    45
# Comp:  2              HeII4687     0.1453      0.41     -71    45
# Comp:  2               HeI5876    0.04710      0.41     -71    45
# Comp:  2          [OIII]5007_d      4.252      0.52     -71    45
# Comp:  2            [OI]6300_d      1.091      0.52     -71    45
# Comp:  2           [NII]6583_d      3.234      0.52     -71    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -50        62
#  comp.  2:       -62        54
# chi2/DOF: 0.8992; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.333      0.44     -50    62
# Comp:  1                Halpha      19.17      0.44     -50    62
# Comp:  2             [SII]6716      4.785      0.43     -62    54
# Comp:  2             [SII]6731      3.895      0.43     -62    54
# Comp:  2              HeII4687      0.000      0.43     -62    54
# Comp:  2               HeI5876      0.000      0.43     -62    54
# Comp:  2          [OIII]5007_d      4.689      0.54     -62    54
# Comp:  2            [OI]6300_d      1.368      0.54     -62    54
# Comp:  2           [NII]6583_d      3.730      0.54     -62    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        31
#  comp.  1:       -52        56
#  comp.  2:       -64        45
# chi2/DOF: 0.9004; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.227      0.43     -52    56
# Comp:  1                Halpha      18.56      0.43     -52    56
# Comp:  2             [SII]6716      4.604      0.41     -64    45
# Comp:  2             [SII]6731      3.702      0.41     -64    45
# Comp:  2              HeII4687     0.1401      0.41     -64    45
# Comp:  2               HeI5876    0.02584      0.41     -64    45
# Comp:  2          [OIII]5007_d      3.822      0.52     -64    45
# Comp:  2            [OI]6300_d      1.709      0.52     -64    45
# Comp:  2           [NII]6583_d      3.378      0.52     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        10
#  comp.  1:       -50        60
#  comp.  2:       -64        54
# chi2/DOF: 0.9006; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.908      0.44     -50    60
# Comp:  1                Halpha      18.69      0.44     -50    60
# Comp:  2             [SII]6716      4.885      0.43     -64    54
# Comp:  2             [SII]6731      3.772      0.43     -64    54
# Comp:  2              HeII4687      0.000      0.43     -64    54
# Comp:  2               HeI5876     0.1542      0.43     -64    54
# Comp:  2          [OIII]5007_d      4.658      0.54     -64    54
# Comp:  2            [OI]6300_d      1.502      0.54     -64    54
# Comp:  2           [NII]6583_d      3.881      0.54     -64    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        30
#  comp.  1:       -54        55
#  comp.  2:       -66        50
# chi2/DOF: 0.8990; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.548      0.43     -54    55
# Comp:  1                Halpha      18.47      0.43     -54    55
# Comp:  2             [SII]6716      4.503      0.42     -66    50
# Comp:  2             [SII]6731      2.969      0.42     -66    50
# Comp:  2              HeII4687     0.1243      0.42     -66    50
# Comp:  2               HeI5876      0.000      0.42     -66    50
# Comp:  2          [OIII]5007_d      4.966      0.53     -66    50
# Comp:  2            [OI]6300_d      1.615      0.53     -66    50
# Comp:  2           [NII]6583_d      3.823      0.53     -66    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -52        59
#  comp.  2:       -63        57
# chi2/DOF: 0.9022; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.117      0.43     -52    59
# Comp:  1                Halpha      18.58      0.43     -52    59
# Comp:  2             [SII]6716      4.979      0.43     -63    57
# Comp:  2             [SII]6731      3.542      0.43     -63    57
# Comp:  2              HeII4687      0.000      0.43     -63    57
# Comp:  2               HeI5876    0.01778      0.43     -63    57
# Comp:  2          [OIII]5007_d      4.976      0.54     -63    57
# Comp:  2            [OI]6300_d      1.869      0.54     -63    57
# Comp:  2           [NII]6583_d      3.810      0.54     -63    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        29
#  comp.  1:       -48        58
#  comp.  2:       -65        46
# chi2/DOF: 0.9031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.481      0.43     -48    58
# Comp:  1                Halpha      18.69      0.43     -48    58
# Comp:  2             [SII]6716      4.670      0.41     -65    46
# Comp:  2             [SII]6731      3.368      0.41     -65    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.380      0.44     -51    63
# Comp:  1                Halpha      19.14      0.44     -51    63
# Comp:  2             [SII]6716      4.697      0.41     -66    44
# Comp:  2             [SII]6731      3.330      0.41     -66    44
# Comp:  2              HeII4687      0.000      0.41     -66    44
# Comp:  2               HeI5876    0.09058      0.41     -66    44
# Comp:  2          [OIII]5007_d      3.963      0.52     -66    44
# Comp:  2            [OI]6300_d      1.589      0.52     -66    44
# Comp:  2           [NII]6583_d      4.007      0.52     -66    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        54
#  comp.  1:       -51        60
#  comp.  2:       -65        48
# chi2/DOF: 0.9012; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.503      0.44     -51    60
# Comp:  1                Halpha      18.59      0.44     -51    60
# Comp:  2             [SII]6716      4.582      0.42     -65    48
# Comp:  2             [SII]6731      3.053      0.42     -65    48
# Comp:  2              HeII4687     0.5262      0.42     -65    48
# Comp:  2               HeI5876     0.2700      0.42     -65    48
# Comp:  2          [OIII]5007_d      4.888      0.53     -65    48
# Comp:  2            [OI]6300_d      1.922      0.53     -65    48
# Comp:  2           [NII]6583_d      3.540      0.53     -65    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        33
#  comp.  1:       -50        59
#  comp.  2:       -73        39
# chi2/DOF: 0.8989; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.035      0.43     -50    59
# Comp:  1                Halpha      19.23      0.43     -50    59
# Comp:  2             [SII]6716      4.483      0.40     -73    39
# Comp:  2             [SII]6731      3.278      0.40     -73    39
# Comp:  2              HeII4687      0.000      0.40     -73    39
# Comp:  2               HeI5876     0.1327      0.40     -73    39
# Comp:  2          [OIII]5007_d      4.329      0.51     -73    39
# Comp:  2            [OI]6300_d      1.870      0.51     -73    39
# Comp:  2           [NII]6583_d      3.116      0.51     -73    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        33
#  comp.  1:       -56        61
#  comp.  2:       -59        55
# chi2/DOF: 0.9018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.892      0.44     -56    61
# Comp:  1                Halpha      18.88      0.44     -56    61
# Comp:  2             [SII]6716      4.749      0.43     -59    55
# Comp:  2             [SII]6731      3.736      0.43     -59    55
# Comp:  2              HeII4687     0.5631      0.43     -59    55
# Comp:  2               HeI5876     0.1811      0.43     -59    55
# Comp:  2          [OIII]5007_d      4.360      0.54     -59    55
# Comp:  2            [OI]6300_d      1.354      0.54     -59    55
# Comp:  2           [NII]6583_d      4.042      0.54     -59    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -52        54
#  comp.  2:       -61        45
# chi2/DOF: 0.8951; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.743      0.43     -52    54
# Comp:  1                Halpha      18.89      0.43     -52    54
# Comp:  2             [SII]6716      4.418      0.41     -61    45
# Comp:  2             [SII]6731      2.958      0.41     -61    45
# Comp:  2              HeII4687     0.3828      0.41     -61    45
# Comp:  2               HeI5876     0.2149      0.41     -61    45
# Comp:  2          [OIII]5007_d      4.321      0.52     -61    45
# Comp:  2            [OI]6300_d      1.420      0.52     -61    45
# Comp:  2           [NII]6583_d      3.192      0.52     -61    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -53        58
#  comp.  2:       -72        38
# chi2/DOF: 0.8968; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.358      0.43     -53    58
# Comp:  1                Halpha      18.68      0.43     -53    58
# Comp:  2             [SII]6716      4.543      0.40     -72    38
# Comp:  2             [SII]6731      3.303      0.40     -72    38
# Comp:  2              HeII4687      0.000      0.40     -72    38
# Comp:  2               HeI5876     0.1634      0.40     -72    38
# Comp:  2          [OIII]5007_d      4.501      0.51     -72    38
# Comp:  2            [OI]6300_d      1.185      0.51     -72    38
# Comp:  2           [NII]6583_d      3.481      0.51     -72    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        22
#  comp.  1:       -52        59
#  comp.  2:       -67        50
# chi2/DOF: 0.8991; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.982      0.43     -52    59
# Comp:  1                Halpha      18.96      0.43     -52    59
# Comp:  2             [SII]6716      4.563      0.42     -67    50
# Comp:  2             [SII]6731      3.682      0.42     -67    50
# Comp:  2              HeII4687     0.4183      0.42     -67    50
# Comp:  2               HeI5876     0.1567      0.42     -67    50
# Comp:  2          [OIII]5007_d      4.895      0.53     -67    50
# Comp:  2            [OI]6300_d      1.121      0.53     -67    50
# Comp:  2           [NII]6583_d      4.045      0.53     -67    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -52        59
#  comp.  2:       -64        52
# chi2/DOF: 0.8999; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.502      0.43     -52    59
# Comp:  1                Halpha      19.03      0.43     -52    59
# Comp:  2             [SII]6716      4.799      0.42     -64    52
# Comp:  2             [SII]6731      3.036      0.42     -64    52
# Comp:  2              HeII4687    0.06489      0.42     -64    52
# Comp:  2               HeI5876      0.000      0.42     -64    52
# Comp:  2          [OIII]5007_d      4.787      0.53     -64    52
# Comp:  2            [OI]6300_d      1.342      0.53     -64    52
# Comp:  2           [NII]6583_d      3.879      0.53     -64    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        70
#  comp.  1:       -54        59
#  comp.  2:       -56        52
# chi2/DOF: 0.9012; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.864      0.43     -54    59
# Comp:  1                Halpha      18.75      0.43     -54    59
# Comp:  2             [SII]6716      4.794      0.42     -56    52
# Comp:  2             [SII]6731      3.389      0.42     -56    52
# Comp:  2              HeII4687     0.1391      0.42     -56    52
# Comp:  2               HeI5876     0.1421      0.42     -56    52
# Comp:  2          [OIII]5007_d      4.380      0.53     -56    52
# Comp:  2            [OI]6300_d      2.021      0.53     -56    52
# Comp:  2           [NII]6583_d      4.000      0.53     -56    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        71
#  comp.  1:       -51        60
#  comp.  2:       -64        42
# chi2/DOF: 0.8983; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.709      0.44     -51    60
# Comp:  1                Halpha      19.04      0.44     -51    60
# Comp:  2             [SII]6716      4.527      0.41     -64    42
# Comp:  2             [SII]6731      3.489      0.41     -64    42
# Comp:  2              HeII4687      0.000      0.41     -64    42
# Comp:  2               HeI5876    0.09849      0.41     -64    42
# Comp:  2          [OIII]5007_d      3.857      0.52     -64    42
# Comp:  2            [OI]6300_d      2.089      0.52     -64    42
# Comp:  2           [NII]6583_d      3.273      0.52     -64    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         5
#  comp.  1:       -54        60
#  comp.  2:       -67        40
# chi2/DOF: 0.8978; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.193      0.44     -54    60
# Comp:  1                Halpha      18.72      0.44     -54    60
# Comp:  2             [SII]6716      4.534      0.41     -67    40
# Comp:  2             [SII]6731      3.218      0.41     -67    40
# Comp:  2              HeII4687    0.04182      0.41     -67    40
# Comp:  2               HeI5876    0.05052      0.41     -67    40
# Comp:  2          [OIII]5007_d      3.789      0.51     -67    40
# Comp:  2            [OI]6300_d      1.785      0.51     -67    40
# Comp:  2           [NII]6583_d      3.523      0.51     -67    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        78
#  comp.  1:       -49        63
#  comp.  2:       -60        45
# chi2/DOF: 0.9010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.978      0.44     -49    63
# Comp:  1                Halpha      19.28      0.44     -49    63
# Comp:  2             [SII]6716      4.572      0.41     -60    45
# Comp:  2             [SII]6731      3.604      0.41     -60    45
# Comp:  2              HeII4687     0.4873      0.41     -60    45
# Comp:  2               HeI5876      0.000      0.41     -60    45
# Comp:  2          [OIII]5007_d      4.292      0.52     -60    45
# Comp:  2            [OI]6300_d      1.415      0.52     -60    45
# Comp:  2           [NII]6583_d      3.152      0.52     -60    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        32
#  comp.  1:       -52        57
#  comp.  2:       -73        42
# chi2/DOF: 0.8986; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.939      0.43     -52    57
# Comp:  1                Halpha      18.71      0.43     -52    57
# Comp:  2             [SII]6716      4.580      0.41     -73    42
# Comp:  2             [SII]6731      3.348      0.41     -73    42
# Comp:  2              HeII4687      0.000      0.41     -73    42
# Comp:  2               HeI5876    0.04215      0.41     -73    42
# Comp:  2          [OIII]5007_d      4.621      0.51     -73    42
# Comp:  2            [OI]6300_d      1.553      0.51     -73    42
# Comp:  2           [NII]6583_d      3.462      0.51     -73    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -51        60
#  comp.  2:       -72        41
# chi2/DOF: 0.9000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.976      0.44     -51    60
# Comp:  1                Halpha      19.21      0.44     -51    60
# Comp:  2             [SII]6716      4.621      0.41     -72    41
# Comp:  2             [SII]6731      3.281      0.41     -72    41
# Comp:  2              HeII4687      0.000      0.41     -72    41
# Comp:  2               HeI5876     0.1021      0.41     -72    41
# Comp:  2          [OIII]5007_d      4.462      0.51     -72    41
# Comp:  2            [OI]6300_d      1.253      0.51     -72    41
# Comp:  2           [NII]6583_d      3.262      0.51     -72    41
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.56185399, 0.44039157, 0.18896374, 0.34733774, 0.17094364,
#        0.10053533, 0.47087788, 0.39019474, 0.35821326])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 6.02143232, 25.3272089 ,  6.49561761,  4.7170431 ,  0.        ,
#         0.        ,  4.60780857,  2.05633253,  4.93189209])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.249243    0.023257
# 1        Halpha  1.048360    0.018229
# 2     [SII]6716  0.268871    0.007822
# 3     [SII]6731  0.195251    0.014377
# 4      HeII4687  0.000000    0.007076
# 5       HeI5876  0.000000    0.004161
# 6  [OIII]5007_d  0.190729    0.019491
# 7    [OI]6300_d  0.085117    0.016151
# 8   [NII]6583_d  0.204144    0.014827
#           Name      Flux  Error_flux
# 0        Hbeta  0.249243    0.023257
# 1       Halpha  1.048360    0.018229
# 2    [SII]6716  0.268871    0.007822
# 3    [SII]6731  0.195251    0.014377
# 4     HeII4687  0.000000    0.007076
# 5      HeI5876  0.000000    0.004161
# 6   [OIII]4959  0.047682    0.019491
# 7   [OIII]5007  0.143047    0.019491
# 8     [OI]6300  0.063838    0.016151
# 9     [OI]6364  0.021279    0.016151
# 10   [NII]6548  0.051036    0.014827
# 11   [NII]6583  0.153108    0.014827

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0413926193138212
