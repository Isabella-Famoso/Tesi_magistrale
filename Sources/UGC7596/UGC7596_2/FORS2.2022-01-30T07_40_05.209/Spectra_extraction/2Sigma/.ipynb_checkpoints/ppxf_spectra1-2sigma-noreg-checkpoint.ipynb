# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = 0.00189
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
# chi2/DOF: 0.01249; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         9
# chi2/DOF: 0.007164; DOF: 1912; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.25227436 1.278207   1.31605046 ... 0.68766457 0.7428345  0.71499185]
# [1.21240798 1.22860029 1.22841379 ... 0.78729623 0.77640933 0.76912226]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-58.95668563,   8.9739709 ])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70         1
#  comp.  2:      -158        91
# chi2/DOF: 0.9757; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5376      0.21     -70     1
# Comp:  1                Halpha     0.7651      0.21     -70     1
# Comp:  2             [SII]6716     0.2364      0.28    -158    91
# Comp:  2             [SII]6731     0.4338      0.28    -158    91
# Comp:  2              HeII4687     0.1010      0.28    -158    91
# Comp:  2               HeI5876     0.1572      0.28    -158    91
# Comp:  2          [OIII]5007_d     0.6639      0.35    -158    91
# Comp:  2            [OI]6300_d     0.7103      0.35    -158    91
# Comp:  2           [NII]6583_d     0.4979      0.35    -158    91
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  2.233; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  2.994; gas flux:      1 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.6087; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.104; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.2592; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.4021; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  1.263; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.346; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.9612; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        42
#  comp.  1:       -72        27
#  comp.  2:      -331       338
# chi2/DOF: 0.9611; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.057      0.22     -72    27
# Comp:  1                Halpha     0.8652      0.22     -72    27
# Comp:  2             [SII]6716      0.000      0.54    -331   338
# Comp:  2             [SII]6731     0.7923      0.54    -331   338
# Comp:  2              HeII4687     0.5746      0.49    -331   338
# Comp:  2               HeI5876     0.5331      0.49    -331   338
# Comp:  2          [OIII]5007_d      1.070      0.62    -331   338
# Comp:  2            [OI]6300_d      3.561      0.62    -331   338
# Comp:  2           [NII]6583_d     0.1784      0.62    -331   338
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -12        39
#  comp.  2:      -186       124
# chi2/DOF: 0.9694; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7130      0.23     -12    39
# Comp:  1                Halpha     0.6091      0.23     -12    39
# Comp:  2             [SII]6716     0.2547      0.31    -186   124
# Comp:  2             [SII]6731     0.6868      0.31    -186   124
# Comp:  2              HeII4687    0.06147      0.31    -186   124
# Comp:  2               HeI5876     0.3959      0.31    -186   124
# Comp:  2          [OIII]5007_d     0.8940      0.40    -186   124
# Comp:  2            [OI]6300_d     0.7822      0.40    -186   124
# Comp:  2           [NII]6583_d     0.6353      0.40    -186   124
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        35
#  comp.  1:       -36         1
#  comp.  2:      -158        96
# chi2/DOF: 0.9667; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5895      0.21     -36     1
# Comp:  1                Halpha     0.7509      0.21     -36     1
# Comp:  2             [SII]6716     0.3691      0.28    -158    96
# Comp:  2             [SII]6731     0.3618      0.28    -158    96
# Comp:  2              HeII4687     0.3379      0.28    -158    96
# Comp:  2               HeI5876    0.08127      0.28    -158    96
# Comp:  2          [OIII]5007_d     0.4486      0.36    -158    96
# Comp:  2            [OI]6300_d     0.5075      0.36    -158    96
# Comp:  2           [NII]6583_d     0.3999      0.36    -158    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -94         1
#  comp.  2:      -151       110
# chi2/DOF: 0.9650; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7842      0.21     -94     1
# Comp:  1                Halpha     0.6089      0.21     -94     1
# Comp:  2             [SII]6716     0.4097      0.30    -151   110
# Comp:  2             [SII]6731     0.2426      0.30    -151   110
# Comp:  2              HeII4687      0.000      0.30    -151   110
# Comp:  2               HeI5876      0.000      0.30    -151   110
# Comp:  2          [OIII]5007_d     0.9087      0.38    -151   110
# Comp:  2            [OI]6300_d     0.4827      0.38    -151   110
# Comp:  2           [NII]6583_d     0.6697      0.38    -151   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70        30
#  comp.  2:      -157        91
# chi2/DOF: 0.9681; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6911      0.23     -70    30
# Comp:  1                Halpha      1.086      0.23     -70    30
# Comp:  2             [SII]6716     0.3680      0.28    -157    91
# Comp:  2             [SII]6731     0.4046      0.28    -157    91
# Comp:  2              HeII4687     0.1843      0.28    -157    91
# Comp:  2               HeI5876     0.1929      0.28    -157    91
# Comp:  2          [OIII]5007_d     0.6530      0.35    -157    91
# Comp:  2            [OI]6300_d     0.5153      0.35    -157    91
# Comp:  2           [NII]6583_d     0.4948      0.35    -157    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        55
#  comp.  1:        -8        58
#  comp.  2:      -272       206
# chi2/DOF: 0.9649; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9097      0.25      -8    58
# Comp:  1                Halpha     0.5589      0.25      -8    58
# Comp:  2             [SII]6716     0.2079      0.39    -272   206
# Comp:  2             [SII]6731     0.1290      0.39    -272   206
# Comp:  2              HeII4687      0.000      0.39    -272   206
# Comp:  2               HeI5876     0.5784      0.39    -272   206
# Comp:  2          [OIII]5007_d      1.074      0.49    -272   206
# Comp:  2            [OI]6300_d      2.109      0.49    -272   206
# Comp:  2           [NII]6583_d     0.4698      0.49    -272   206
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        22
#  comp.  1:       -73         1
#  comp.  2:      -151       106
# chi2/DOF: 0.9708; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5035      0.21     -73     1
# Comp:  1                Halpha     0.6580      0.21     -73     1
# Comp:  2             [SII]6716     0.4244      0.30    -151   106
# Comp:  2             [SII]6731     0.4201      0.30    -151   106
# Comp:  2              HeII4687     0.1736      0.30    -151   106
# Comp:  2               HeI5876      0.000      0.30    -151   106
# Comp:  2          [OIII]5007_d     0.6291      0.37    -151   106
# Comp:  2            [OI]6300_d      1.003      0.37    -151   106
# Comp:  2           [NII]6583_d     0.3710      0.37    -151   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        51
#  comp.  1:       -98         1
#  comp.  2:      -133        86
# chi2/DOF: 0.9646; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5615      0.21     -98     1
# Comp:  1                Halpha     0.5496      0.21     -98     1
# Comp:  2             [SII]6716     0.4741      0.27    -133    86
# Comp:  2             [SII]6731     0.6889      0.27    -133    86
# Comp:  2              HeII4687      0.000      0.27    -133    86
# Comp:  2               HeI5876      0.000      0.27    -133    86
# Comp:  2          [OIII]5007_d     0.7473      0.35    -133    86
# Comp:  2            [OI]6300_d     0.6853      0.35    -133    86
# Comp:  2           [NII]6583_d     0.4211      0.35    -133    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        19
#  comp.  1:       -71        55
#  comp.  2:      -157        92
# chi2/DOF: 0.9687; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4042      0.25     -71    55
# Comp:  1                Halpha      1.030      0.25     -71    55
# Comp:  2             [SII]6716     0.3649      0.28    -157    92
# Comp:  2             [SII]6731     0.2816      0.28    -157    92
# Comp:  2              HeII4687      0.000      0.28    -157    92
# Comp:  2               HeI5876    0.05152      0.28    -157    92
# Comp:  2          [OIII]5007_d     0.5117      0.35    -157    92
# Comp:  2            [OI]6300_d     0.5889      0.35    -157    92
# Comp:  2           [NII]6583_d     0.3363      0.35    -157    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        35
#  comp.  1:       -88         1
#  comp.  2:      -163        66
# chi2/DOF: 0.9691; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9407      0.21     -88     1
# Comp:  1                Halpha      1.160      0.21     -88     1
# Comp:  2             [SII]6716     0.1823      0.26    -163    66
# Comp:  2             [SII]6731     0.2723      0.26    -163    66
# Comp:  2              HeII4687    0.08277      0.26    -163    66
# Comp:  2               HeI5876     0.4484      0.26    -163    66
# Comp:  2          [OIII]5007_d     0.7182      0.32    -163    66
# Comp:  2            [OI]6300_d     0.8079      0.32    -163    66
# Comp:  2           [NII]6583_d     0.4812      0.32    -163    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        52
#  comp.  1:       -54        56
#  comp.  2:      -141       105
# chi2/DOF: 0.9624; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.099      0.25     -54    56
# Comp:  1                Halpha     0.8129      0.25     -54    56
# Comp:  2             [SII]6716    0.06968      0.29    -141   105
# Comp:  2             [SII]6731     0.4087      0.29    -141   105
# Comp:  2              HeII4687    0.06622      0.29    -141   105
# Comp:  2               HeI5876     0.2680      0.29    -141   105
# Comp:  2          [OIII]5007_d     0.7992      0.37    -141   105
# Comp:  2            [OI]6300_d     0.3383      0.37    -141   105
# Comp:  2           [NII]6583_d     0.6243      0.37    -141   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -43        61
#  comp.  2:      -394       256
# chi2/DOF: 0.9618; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 105; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8658      0.25     -43    61
# Comp:  1                Halpha     0.8755      0.25     -43    61
# Comp:  2             [SII]6716     0.2734      0.44    -394   256
# Comp:  2             [SII]6731     0.7477      0.44    -394   256
# Comp:  2              HeII4687     0.3306      0.43    -394   256
# Comp:  2               HeI5876      0.000      0.43    -394   256
# Comp:  2          [OIII]5007_d     0.5971      0.54    -394   256
# Comp:  2            [OI]6300_d      2.584      0.54    -394   256
# Comp:  2           [NII]6583_d     0.5957      0.54    -394   256
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        38
#  comp.  1:       -87         1
#  comp.  2:      -178        72
# chi2/DOF: 0.9672; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9365      0.21     -87     1
# Comp:  1                Halpha     0.9828      0.21     -87     1
# Comp:  2             [SII]6716     0.2218      0.26    -178    72
# Comp:  2             [SII]6731     0.4954      0.26    -178    72
# Comp:  2              HeII4687     0.2870      0.26    -178    72
# Comp:  2               HeI5876     0.2085      0.26    -178    72
# Comp:  2          [OIII]5007_d     0.5277      0.33    -178    72
# Comp:  2            [OI]6300_d     0.9305      0.33    -178    72
# Comp:  2           [NII]6583_d     0.5090      0.33    -178    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -90         1
#  comp.  2:      -151        95
# chi2/DOF: 0.9657; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7436      0.21     -90     1
# Comp:  1                Halpha     0.7711      0.21     -90     1
# Comp:  2             [SII]6716     0.4440      0.28    -151    95
# Comp:  2             [SII]6731     0.6367      0.28    -151    95
# Comp:  2              HeII4687      0.000      0.28    -151    95
# Comp:  2               HeI5876      0.000      0.28    -151    95
# Comp:  2          [OIII]5007_d     0.8175      0.36    -151    95
# Comp:  2            [OI]6300_d     0.7074      0.36    -151    95
# Comp:  2           [NII]6583_d     0.3394      0.36    -151    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70        19
#  comp.  2:      -158        89
# chi2/DOF: 0.9704; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8002      0.22     -70    19
# Comp:  1                Halpha     0.9805      0.22     -70    19
# Comp:  2             [SII]6716     0.3778      0.28    -158    89
# Comp:  2             [SII]6731     0.4480      0.28    -158    89
# Comp:  2              HeII4687      0.000      0.28    -158    89
# Comp:  2               HeI5876    0.07625      0.28    -158    89
# Comp:  2          [OIII]5007_d     0.6759      0.35    -158    89
# Comp:  2            [OI]6300_d     0.7644      0.35    -158    89
# Comp:  2           [NII]6583_d     0.5751      0.35    -158    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        46
#  comp.  1:       -60        29
#  comp.  2:      -193       111
# chi2/DOF: 0.9691; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2694      0.22     -60    29
# Comp:  1                Halpha     0.9253      0.22     -60    29
# Comp:  2             [SII]6716     0.4377      0.30    -193   111
# Comp:  2             [SII]6731     0.3153      0.30    -193   111
# Comp:  2              HeII4687      0.000      0.30    -193   111
# Comp:  2               HeI5876    0.01833      0.30    -193   111
# Comp:  2          [OIII]5007_d     0.5290      0.38    -193   111
# Comp:  2            [OI]6300_d      1.023      0.38    -193   111
# Comp:  2           [NII]6583_d     0.6217      0.38    -193   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        19
#  comp.  1:       -70        33
#  comp.  2:      -158        87
# chi2/DOF: 0.9689; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7438      0.23     -70    33
# Comp:  1                Halpha     0.6894      0.23     -70    33
# Comp:  2             [SII]6716     0.3105      0.28    -158    87
# Comp:  2             [SII]6731     0.5001      0.28    -158    87
# Comp:  2              HeII4687    0.06182      0.28    -158    87
# Comp:  2               HeI5876    0.08834      0.28    -158    87
# Comp:  2          [OIII]5007_d     0.7516      0.35    -158    87
# Comp:  2            [OI]6300_d      1.091      0.35    -158    87
# Comp:  2           [NII]6583_d     0.3120      0.35    -158    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         7
#  comp.  1:       -67        44
#  comp.  2:      -175        80
# chi2/DOF: 0.9632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2454      0.24     -67    44
# Comp:  1                Halpha      1.083      0.24     -67    44
# Comp:  2             [SII]6716     0.3809      0.27    -175    80
# Comp:  2             [SII]6731     0.5829      0.27    -175    80
# Comp:  2              HeII4687     0.1130      0.27    -175    80
# Comp:  2               HeI5876      0.000      0.27    -175    80
# Comp:  2          [OIII]5007_d     0.8081      0.34    -175    80
# Comp:  2            [OI]6300_d     0.1849      0.34    -175    80
# Comp:  2           [NII]6583_d     0.5860      0.34    -175    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        22
#  comp.  1:       -70        32
#  comp.  2:      -158        93
# chi2/DOF: 0.9671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3965      0.23     -70    32
# Comp:  1                Halpha     0.9541      0.23     -70    32
# Comp:  2             [SII]6716     0.3088      0.28    -158    93
# Comp:  2             [SII]6731     0.2635      0.28    -158    93
# Comp:  2              HeII4687      0.000      0.28    -158    93
# Comp:  2               HeI5876     0.3083      0.28    -158    93
# Comp:  2          [OIII]5007_d     0.7378      0.36    -158    93
# Comp:  2            [OI]6300_d     0.7653      0.36    -158    93
# Comp:  2           [NII]6583_d     0.4366      0.36    -158    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        25
#  comp.  1:       -52        46
#  comp.  2:      -184       116
# chi2/DOF: 0.9697; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.092      0.24     -52    46
# Comp:  1                Halpha      1.127      0.24     -52    46
# Comp:  2             [SII]6716     0.1821      0.31    -184   116
# Comp:  2             [SII]6731     0.7313      0.31    -184   116
# Comp:  2              HeII4687     0.4952      0.31    -184   116
# Comp:  2               HeI5876     0.1697      0.31    -184   116
# Comp:  2          [OIII]5007_d     0.8944      0.39    -184   116
# Comp:  2            [OI]6300_d     0.8509      0.39    -184   116
# Comp:  2           [NII]6583_d     0.4124      0.39    -184   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -30        56
#  comp.  2:      -154       111
# chi2/DOF: 0.9661; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7832      0.25     -30    56
# Comp:  1                Halpha     0.6163      0.25     -30    56
# Comp:  2             [SII]6716     0.4513      0.30    -154   111
# Comp:  2             [SII]6731     0.8461      0.30    -154   111
# Comp:  2              HeII4687     0.3272      0.30    -154   111
# Comp:  2               HeI5876    0.03981      0.30    -154   111
# Comp:  2          [OIII]5007_d     0.5866      0.38    -154   111
# Comp:  2            [OI]6300_d     0.8561      0.38    -154   111
# Comp:  2           [NII]6583_d     0.6685      0.38    -154   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        20
#  comp.  1:       -70        24
#  comp.  2:      -158        90
# chi2/DOF: 0.9714; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3966      0.22     -70    24
# Comp:  1                Halpha     0.5555      0.22     -70    24
# Comp:  2             [SII]6716     0.3686      0.28    -158    90
# Comp:  2             [SII]6731     0.4977      0.28    -158    90
# Comp:  2              HeII4687      0.000      0.28    -158    90
# Comp:  2               HeI5876     0.1707      0.28    -158    90
# Comp:  2          [OIII]5007_d     0.7118      0.35    -158    90
# Comp:  2            [OI]6300_d     0.7498      0.35    -158    90
# Comp:  2           [NII]6583_d     0.6180      0.35    -158    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -91         1
#  comp.  2:      -148        69
# chi2/DOF: 0.9714; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5018      0.21     -91     1
# Comp:  1                Halpha     0.8709      0.21     -91     1
# Comp:  2             [SII]6716     0.2692      0.26    -148    69
# Comp:  2             [SII]6731     0.4223      0.26    -148    69
# Comp:  2              HeII4687     0.3088      0.26    -148    69
# Comp:  2               HeI5876     0.1311      0.26    -148    69
# Comp:  2          [OIII]5007_d     0.5712      0.33    -148    69
# Comp:  2            [OI]6300_d     0.7686      0.33    -148    69
# Comp:  2           [NII]6583_d     0.3175      0.33    -148    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        11
#  comp.  1:       -73         1
#  comp.  2:      -260       116
# chi2/DOF: 0.9663; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3396      0.21     -73     1
# Comp:  1                Halpha     0.6241      0.21     -73     1
# Comp:  2             [SII]6716      0.000      0.31    -260   116
# Comp:  2             [SII]6731     0.4259      0.31    -260   116
# Comp:  2              HeII4687     0.5951      0.31    -260   116
# Comp:  2               HeI5876     0.2235      0.31    -260   116
# Comp:  2          [OIII]5007_d     0.7069      0.39    -260   116
# Comp:  2            [OI]6300_d     0.5529      0.39    -260   116
# Comp:  2           [NII]6583_d     0.6519      0.39    -260   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        22
#  comp.  1:       -91         1
#  comp.  2:      -174       109
# chi2/DOF: 0.9681; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3774      0.21     -91     1
# Comp:  1                Halpha     0.8466      0.21     -91     1
# Comp:  2             [SII]6716    0.05354      0.30    -174   109
# Comp:  2             [SII]6731     0.4929      0.30    -174   109
# Comp:  2              HeII4687      0.000      0.30    -174   109
# Comp:  2               HeI5876     0.1764      0.30    -174   109
# Comp:  2          [OIII]5007_d     0.8481      0.38    -174   109
# Comp:  2            [OI]6300_d     0.9433      0.38    -174   109
# Comp:  2           [NII]6583_d     0.3186      0.38    -174   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        31
#  comp.  1:       -43        40
#  comp.  2:      -165        58
# chi2/DOF: 0.9705; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7300      0.23     -43    40
# Comp:  1                Halpha      1.030      0.23     -43    40
# Comp:  2             [SII]6716     0.1635      0.25    -165    58
# Comp:  2             [SII]6731     0.3889      0.25    -165    58
# Comp:  2              HeII4687     0.2412      0.25    -165    58
# Comp:  2               HeI5876     0.2596      0.25    -165    58
# Comp:  2          [OIII]5007_d     0.5926      0.31    -165    58
# Comp:  2            [OI]6300_d     0.6957      0.31    -165    58
# Comp:  2           [NII]6583_d     0.4307      0.31    -165    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -69        45
#  comp.  2:      -116        97
# chi2/DOF: 0.9684; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8447      0.24     -69    45
# Comp:  1                Halpha      1.062      0.24     -69    45
# Comp:  2             [SII]6716    0.08725      0.29    -116    97
# Comp:  2             [SII]6731     0.5408      0.29    -116    97
# Comp:  2              HeII4687    0.02857      0.29    -116    97
# Comp:  2               HeI5876     0.3886      0.29    -116    97
# Comp:  2          [OIII]5007_d     0.6839      0.36    -116    97
# Comp:  2            [OI]6300_d     0.4143      0.36    -116    97
# Comp:  2           [NII]6583_d     0.6103      0.36    -116    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        19
#  comp.  1:       -75         4
#  comp.  2:      -143        74
# chi2/DOF: 0.9661; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6124      0.21     -75     4
# Comp:  1                Halpha      1.081      0.21     -75     4
# Comp:  2             [SII]6716     0.2532      0.26    -143    74
# Comp:  2             [SII]6731     0.3605      0.26    -143    74
# Comp:  2              HeII4687     0.2699      0.26    -143    74
# Comp:  2               HeI5876    0.05256      0.26    -143    74
# Comp:  2          [OIII]5007_d     0.5024      0.33    -143    74
# Comp:  2            [OI]6300_d     0.6970      0.33    -143    74
# Comp:  2           [NII]6583_d     0.5425      0.33    -143    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        24
#  comp.  1:       -69        62
#  comp.  2:      -155        94
# chi2/DOF: 0.9699; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9316      0.25     -69    62
# Comp:  1                Halpha     0.8063      0.25     -69    62
# Comp:  2             [SII]6716     0.3587      0.28    -155    94
# Comp:  2             [SII]6731     0.7125      0.28    -155    94
# Comp:  2              HeII4687      0.000      0.28    -155    94
# Comp:  2               HeI5876     0.1356      0.28    -155    94
# Comp:  2          [OIII]5007_d     0.5949      0.36    -155    94
# Comp:  2            [OI]6300_d     0.4141      0.36    -155    94
# Comp:  2           [NII]6583_d     0.4989      0.36    -155    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        60
#  comp.  1:       -71        30
#  comp.  2:      -161        74
# chi2/DOF: 0.9654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.03058      0.23     -71    30
# Comp:  1                Halpha     0.7062      0.23     -71    30
# Comp:  2             [SII]6716     0.2266      0.26    -161    74
# Comp:  2             [SII]6731     0.6112      0.26    -161    74
# Comp:  2              HeII4687     0.1416      0.26    -161    74
# Comp:  2               HeI5876      0.000      0.26    -161    74
# Comp:  2          [OIII]5007_d     0.6614      0.33    -161    74
# Comp:  2            [OI]6300_d     0.4997      0.33    -161    74
# Comp:  2           [NII]6583_d     0.3800      0.33    -161    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        21
#  comp.  1:       -74         1
#  comp.  2:      -128       113
# chi2/DOF: 0.9677; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8195      0.21     -74     1
# Comp:  1                Halpha     0.8361      0.21     -74     1
# Comp:  2             [SII]6716     0.3676      0.30    -128   113
# Comp:  2             [SII]6731     0.5710      0.30    -128   113
# Comp:  2              HeII4687     0.1960      0.30    -128   113
# Comp:  2               HeI5876     0.5450      0.30    -128   113
# Comp:  2          [OIII]5007_d     0.6518      0.38    -128   113
# Comp:  2            [OI]6300_d      1.124      0.38    -128   113
# Comp:  2           [NII]6583_d     0.3428      0.38    -128   113
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        18
#  comp.  1:       -70        33
#  comp.  2:      -158        90
# chi2/DOF: 0.9650; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.143      0.23     -70    33
# Comp:  1                Halpha     0.8563      0.23     -70    33
# Comp:  2             [SII]6716     0.2271      0.28    -158    90
# Comp:  2             [SII]6731     0.4442      0.28    -158    90
# Comp:  2              HeII4687    0.01145      0.28    -158    90
# Comp:  2               HeI5876     0.5731      0.28    -158    90
# Comp:  2          [OIII]5007_d     0.6525      0.35    -158    90
# Comp:  2            [OI]6300_d     0.5393      0.35    -158    90
# Comp:  2           [NII]6583_d     0.7226      0.35    -158    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        19
#  comp.  1:       -70         1
#  comp.  2:      -176        82
# chi2/DOF: 0.9643; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2148      0.21     -70     1
# Comp:  1                Halpha     0.6385      0.21     -70     1
# Comp:  2             [SII]6716     0.2578      0.27    -176    82
# Comp:  2             [SII]6731     0.6007      0.27    -176    82
# Comp:  2              HeII4687      0.000      0.27    -176    82
# Comp:  2               HeI5876     0.2492      0.27    -176    82
# Comp:  2          [OIII]5007_d     0.7068      0.34    -176    82
# Comp:  2            [OI]6300_d     0.6384      0.34    -176    82
# Comp:  2           [NII]6583_d     0.6316      0.34    -176    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -49        52
#  comp.  2:      -136       105
# chi2/DOF: 0.9639; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.431      0.24     -49    52
# Comp:  1                Halpha      1.273      0.24     -49    52
# Comp:  2             [SII]6716     0.1222      0.29    -136   105
# Comp:  2             [SII]6731     0.8388      0.29    -136   105
# Comp:  2              HeII4687      0.000      0.29    -136   105
# Comp:  2               HeI5876     0.4062      0.29    -136   105
# Comp:  2          [OIII]5007_d     0.7407      0.37    -136   105
# Comp:  2            [OI]6300_d      1.166      0.37    -136   105
# Comp:  2           [NII]6583_d     0.8419      0.37    -136   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        50
#  comp.  1:      -107        52
#  comp.  2:      -190       118
# chi2/DOF: 0.9641; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.115      0.24    -107    52
# Comp:  1                Halpha     0.9440      0.24    -107    52
# Comp:  2             [SII]6716     0.2905      0.31    -190   118
# Comp:  2             [SII]6731     0.3187      0.31    -190   118
# Comp:  2              HeII4687     0.3124      0.31    -190   118
# Comp:  2               HeI5876     0.3662      0.31    -190   118
# Comp:  2          [OIII]5007_d     0.5938      0.39    -190   118
# Comp:  2            [OI]6300_d     0.6512      0.39    -190   118
# Comp:  2           [NII]6583_d     0.5941      0.39    -190   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        41
#  comp.  1:       -80         1
#  comp.  2:      -119       119
# chi2/DOF: 0.9674; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4628      0.21     -80     1
# Comp:  1                Halpha     0.7540      0.21     -80     1
# Comp:  2             [SII]6716     0.4502      0.31    -119   119
# Comp:  2             [SII]6731     0.8225      0.31    -119   119
# Comp:  2              HeII4687     0.3121      0.31    -119   119
# Comp:  2               HeI5876     0.3085      0.31    -119   119
# Comp:  2          [OIII]5007_d     0.5085      0.39    -119   119
# Comp:  2            [OI]6300_d      1.067      0.39    -119   119
# Comp:  2           [NII]6583_d     0.7894      0.39    -119   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        18
#  comp.  1:       -65        24
#  comp.  2:      -147        75
# chi2/DOF: 0.9698; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3889      0.22     -65    24
# Comp:  1                Halpha      1.042      0.22     -65    24
# Comp:  2             [SII]6716     0.1386      0.26    -147    75
# Comp:  2             [SII]6731     0.5994      0.26    -147    75
# Comp:  2              HeII4687     0.1702      0.26    -147    75
# Comp:  2               HeI5876     0.4602      0.26    -147    75
# Comp:  2          [OIII]5007_d     0.5186      0.33    -147    75
# Comp:  2            [OI]6300_d     0.8504      0.33    -147    75
# Comp:  2           [NII]6583_d     0.1409      0.33    -147    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -60        28
#  comp.  2:      -157        99
# chi2/DOF: 0.9677; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9144      0.22     -60    28
# Comp:  1                Halpha     0.8569      0.22     -60    28
# Comp:  2             [SII]6716     0.1755      0.29    -157    99
# Comp:  2             [SII]6731     0.6117      0.29    -157    99
# Comp:  2              HeII4687    0.06737      0.29    -157    99
# Comp:  2               HeI5876     0.2032      0.29    -157    99
# Comp:  2          [OIII]5007_d     0.7213      0.36    -157    99
# Comp:  2            [OI]6300_d     0.8785      0.36    -157    99
# Comp:  2           [NII]6583_d     0.7062      0.36    -157    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        29
#  comp.  1:       -30         1
#  comp.  2:      -426       195
# chi2/DOF: 0.9560; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6502      0.21     -30     1
# Comp:  1                Halpha     0.7853      0.21     -30     1
# Comp:  2             [SII]6716     0.2972      0.38    -426   195
# Comp:  2             [SII]6731     0.5043      0.38    -426   195
# Comp:  2              HeII4687     0.7303      0.38    -426   195
# Comp:  2               HeI5876     0.4672      0.38    -426   195
# Comp:  2          [OIII]5007_d     0.2508      0.48    -426   195
# Comp:  2            [OI]6300_d      2.364      0.48    -426   195
# Comp:  2           [NII]6583_d     0.8865      0.48    -426   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70        25
#  comp.  2:      -158        92
# chi2/DOF: 0.9621; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8557      0.22     -70    25
# Comp:  1                Halpha     0.5909      0.22     -70    25
# Comp:  2             [SII]6716     0.2815      0.28    -158    92
# Comp:  2             [SII]6731     0.2963      0.28    -158    92
# Comp:  2              HeII4687     0.2744      0.28    -158    92
# Comp:  2               HeI5876    0.09914      0.28    -158    92
# Comp:  2          [OIII]5007_d     0.5461      0.35    -158    92
# Comp:  2            [OI]6300_d      1.047      0.35    -158    92
# Comp:  2           [NII]6583_d     0.4290      0.35    -158    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        11
#  comp.  1:       -94         1
#  comp.  2:      -173        77
# chi2/DOF: 0.9698; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5591      0.21     -94     1
# Comp:  1                Halpha     0.7416      0.21     -94     1
# Comp:  2             [SII]6716     0.1802      0.27    -173    77
# Comp:  2             [SII]6731     0.6123      0.27    -173    77
# Comp:  2              HeII4687    0.02689      0.27    -173    77
# Comp:  2               HeI5876     0.1951      0.27    -173    77
# Comp:  2          [OIII]5007_d     0.5377      0.34    -173    77
# Comp:  2            [OI]6300_d     0.7592      0.34    -173    77
# Comp:  2           [NII]6583_d     0.7350      0.34    -173    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        21
#  comp.  1:       -69        68
#  comp.  2:      -159        91
# chi2/DOF: 0.9673; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5775      0.26     -69    68
# Comp:  1                Halpha     0.9205      0.26     -69    68
# Comp:  2             [SII]6716     0.1717      0.28    -159    91
# Comp:  2             [SII]6731     0.6315      0.28    -159    91
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4974      0.23     -67    35
# Comp:  1                Halpha     0.8525      0.23     -67    35
# Comp:  2             [SII]6716     0.1521      0.28    -154    92
# Comp:  2             [SII]6731     0.2562      0.28    -154    92
# Comp:  2              HeII4687    0.08923      0.28    -154    92
# Comp:  2               HeI5876     0.2041      0.28    -154    92
# Comp:  2          [OIII]5007_d     0.6120      0.36    -154    92
# Comp:  2            [OI]6300_d      1.126      0.36    -154    92
# Comp:  2           [NII]6583_d     0.5600      0.36    -154    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        25
#  comp.  1:       -75         1
#  comp.  2:      -166        99
# chi2/DOF: 0.9677; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2073      0.21     -75     1
# Comp:  1                Halpha     0.8568      0.21     -75     1
# Comp:  2             [SII]6716     0.3265      0.29    -166    99
# Comp:  2             [SII]6731     0.7495      0.29    -166    99
# Comp:  2              HeII4687     0.4110      0.29    -166    99
# Comp:  2               HeI5876      0.000      0.29    -166    99
# Comp:  2          [OIII]5007_d     0.6065      0.36    -166    99
# Comp:  2            [OI]6300_d     0.6968      0.36    -166    99
# Comp:  2           [NII]6583_d     0.7657      0.36    -166    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        36
#  comp.  1:       -24        85
#  comp.  2:      -330       214
# chi2/DOF: 0.9632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.518      0.27     -24    85
# Comp:  1                Halpha      1.391      0.27     -24    85
# Comp:  2             [SII]6716     0.5960      0.40    -330   214
# Comp:  2             [SII]6731     0.5550      0.40    -330   214
# Comp:  2              HeII4687      0.000      0.40    -330   214
# Comp:  2               HeI5876     0.2581      0.40    -330   214
# Comp:  2          [OIII]5007_d     0.3326      0.50    -330   214
# Comp:  2            [OI]6300_d      2.174      0.50    -330   214
# Comp:  2           [NII]6583_d     0.5832      0.50    -330   214
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -77         1
#  comp.  2:      -128        95
# chi2/DOF: 0.9678; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5804      0.21     -77     1
# Comp:  1                Halpha     0.8531      0.21     -77     1
# Comp:  2             [SII]6716    0.09696      0.28    -128    95
# Comp:  2             [SII]6731     0.6953      0.28    -128    95
# Comp:  2              HeII4687    0.05586      0.28    -128    95
# Comp:  2               HeI5876     0.4847      0.28    -128    95
# Comp:  2          [OIII]5007_d     0.7426      0.36    -128    95
# Comp:  2            [OI]6300_d     0.5929      0.36    -128    95
# Comp:  2           [NII]6583_d     0.4753      0.36    -128    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70        34
#  comp.  2:      -155        90
# chi2/DOF: 0.9613; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.115      0.23     -70    34
# Comp:  1                Halpha      1.029      0.23     -70    34
# Comp:  2             [SII]6716     0.3311      0.28    -155    90
# Comp:  2             [SII]6731     0.3431      0.28    -155    90
# Comp:  2              HeII4687     0.2501      0.28    -155    90
# Comp:  2               HeI5876      0.000      0.28    -155    90
# Comp:  2          [OIII]5007_d     0.5287      0.35    -155    90
# Comp:  2            [OI]6300_d     0.5676      0.35    -155    90
# Comp:  2           [NII]6583_d     0.3558      0.35    -155    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        22
#  comp.  1:       -72         1
#  comp.  2:      -505       211
# chi2/DOF: 0.9502; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6280      0.21     -72     1
# Comp:  1                Halpha     0.7282      0.22     -72     1
# Comp:  2             [SII]6716     0.2695      0.40    -505   211
# Comp:  2             [SII]6731     0.2341      0.40    -505   211
# Comp:  2              HeII4687     0.2189      0.39    -505   211
# Comp:  2               HeI5876     0.2603      0.39    -505   211
# Comp:  2          [OIII]5007_d     0.4561      0.50    -505   211
# Comp:  2            [OI]6300_d      3.670      0.50    -505   211
# Comp:  2           [NII]6583_d      0.000      0.50    -505   211
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        21
#  comp.  1:       -70        17
#  comp.  2:      -158        92
# chi2/DOF: 0.9689; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6391      0.22     -70    17
# Comp:  1                Halpha     0.9770      0.22     -70    17
# Comp:  2             [SII]6716     0.3715      0.28    -158    92
# Comp:  2             [SII]6731     0.7038      0.28    -158    92
# Comp:  2              HeII4687      0.000      0.28    -158    92
# Comp:  2               HeI5876     0.2730      0.28    -158    92
# Comp:  2          [OIII]5007_d     0.5374      0.35    -158    92
# Comp:  2            [OI]6300_d     0.5686      0.35    -158    92
# Comp:  2           [NII]6583_d     0.7582      0.35    -158    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -52        89
#  comp.  2:      -173        94
# chi2/DOF: 0.9687; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.362      0.28     -52    89
# Comp:  1                Halpha     0.9491      0.28     -52    89
# Comp:  2             [SII]6716     0.1846      0.28    -173    94
# Comp:  2             [SII]6731     0.2316      0.28    -173    94
# Comp:  2              HeII4687      0.000      0.28    -173    94
# Comp:  2               HeI5876     0.1857      0.28    -173    94
# Comp:  2          [OIII]5007_d     0.5485      0.36    -173    94
# Comp:  2            [OI]6300_d     0.5657      0.36    -173    94
# Comp:  2           [NII]6583_d     0.7708      0.36    -173    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -87         1
#  comp.  2:      -182       150
# chi2/DOF: 0.9656; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.054      0.21     -87     1
# Comp:  1                Halpha     0.9490      0.21     -87     1
# Comp:  2             [SII]6716     0.1454      0.34    -182   150
# Comp:  2             [SII]6731     0.5422      0.34    -182   150
# Comp:  2              HeII4687     0.3658      0.34    -182   150
# Comp:  2               HeI5876     0.2897      0.34    -182   150
# Comp:  2          [OIII]5007_d     0.6746      0.43    -182   150
# Comp:  2            [OI]6300_d      1.073      0.43    -182   150
# Comp:  2           [NII]6583_d     0.3535      0.43    -182   150
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        85
#  comp.  1:       -49        84
#  comp.  2:      -206        47
# chi2/DOF: 0.9629; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9814      0.27     -49    84
# Comp:  1                Halpha     0.8524      0.27     -49    84
# Comp:  2             [SII]6716     0.1924      0.24    -206    47
# Comp:  2             [SII]6731     0.3020      0.24    -206    47
# Comp:  2              HeII4687     0.1117      0.24    -206    47
# Comp:  2               HeI5876     0.1858      0.24    -206    47
# Comp:  2          [OIII]5007_d     0.5309      0.30    -206    47
# Comp:  2            [OI]6300_d     0.6948      0.30    -206    47
# Comp:  2           [NII]6583_d     0.3413      0.30    -206    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        22
#  comp.  1:       -69        53
#  comp.  2:      -161        96
# chi2/DOF: 0.9683; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9116      0.24     -69    53
# Comp:  1                Halpha      1.203      0.24     -69    53
# Comp:  2             [SII]6716    0.03614      0.29    -161    96
# Comp:  2             [SII]6731     0.2962      0.29    -161    96
# Comp:  2              HeII4687     0.3600      0.29    -161    96
# Comp:  2               HeI5876    0.04446      0.29    -161    96
# Comp:  2          [OIII]5007_d     0.7458      0.36    -161    96
# Comp:  2            [OI]6300_d     0.9599      0.36    -161    96
# Comp:  2           [NII]6583_d     0.3936      0.36    -161    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        20
#  comp.  1:       -70        31
#  comp.  2:      -158        88
# chi2/DOF: 0.9723; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4923      0.23     -70    31
# Comp:  1                Halpha     0.9573      0.23     -70    31
# Comp:  2             [SII]6716    0.09142      0.28    -158    88
# Comp:  2             [SII]6731     0.3824      0.28    -158    88
# Comp:  2              HeII4687      0.000      0.28    -158    88
# Comp:  2               HeI5876    0.05391      0.28    -158    88
# Comp:  2          [OIII]5007_d     0.5870      0.35    -158    88
# Comp:  2            [OI]6300_d     0.5192      0.35    -158    88
# Comp:  2           [NII]6583_d     0.4403      0.35    -158    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        20
#  comp.  1:       -70        35
#  comp.  2:      -159        95
# chi2/DOF: 0.9685; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6543      0.23     -70    35
# Comp:  1                Halpha     0.5902      0.23     -70    35
# Comp:  2             [SII]6716     0.3432      0.28    -159    95
# Comp:  2             [SII]6731     0.3347      0.28    -159    95
# Comp:  2              HeII4687    0.03972      0.28    -159    95
# Comp:  2               HeI5876     0.1715      0.28    -159    95
# Comp:  2          [OIII]5007_d     0.6657      0.36    -159    95
# Comp:  2            [OI]6300_d      1.022      0.36    -159    95
# Comp:  2           [NII]6583_d     0.6511      0.36    -159    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -67        36
#  comp.  2:      -148       162
# chi2/DOF: 0.9704; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4565      0.23     -67    36
# Comp:  1                Halpha     0.7787      0.23     -67    36
# Comp:  2             [SII]6716     0.1170      0.35    -148   162
# Comp:  2             [SII]6731     0.4151      0.35    -148   162
# Comp:  2              HeII4687    0.05292      0.35    -148   162
# Comp:  2               HeI5876     0.1642      0.35    -148   162
# Comp:  2          [OIII]5007_d     0.7890      0.44    -148   162
# Comp:  2            [OI]6300_d     0.6357      0.44    -148   162
# Comp:  2           [NII]6583_d     0.2267      0.44    -148   162
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.33095537, 0.26154135, 0.18840869, 0.2501004 , 0.17672302,
#        0.22240673, 0.20379355, 0.79344397, 0.27350316])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.54509581, 1.04737068, 0.33110416, 0.60898251, 0.09871797,
#        0.19263817, 0.69327318, 0.93334847, 0.68372631])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.039395    0.023919
# 1        Halpha  0.075696    0.018902
# 2     [SII]6716  0.023930    0.013617
# 3     [SII]6731  0.044012    0.018075
# 4      HeII4687  0.007135    0.012772
# 5       HeI5876  0.013922    0.016074
# 6  [OIII]5007_d  0.050104    0.014729
# 7    [OI]6300_d  0.067455    0.057344
# 8   [NII]6583_d  0.049414    0.019767
#           Name      Flux  Error_flux
# 0        Hbeta  0.039395    0.023919
# 1       Halpha  0.075696    0.018902
# 2    [SII]6716  0.023930    0.013617
# 3    [SII]6731  0.044012    0.018075
# 4     HeII4687  0.007135    0.012772
# 5      HeI5876  0.013922    0.016074
# 6   [OIII]4959  0.012526    0.014729
# 7   [OIII]5007  0.037578    0.014729
# 8     [OI]6300  0.050591    0.057344
# 9     [OI]6364  0.016864    0.057344
# 10   [NII]6548  0.012354    0.019767
# 11   [NII]6583  0.037061    0.019767

# %%
np.median(flux_rf_rebin)
# Out:
# 0.07227213008052032
