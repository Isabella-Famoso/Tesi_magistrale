# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt") 
z = 0.00189 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4444.779367   4446.25657507 4447.73378315 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02803925 0.0213098  0.02103924 ... 0.01782334 0.02148723 0.01949645] [0.00400756 0.00400756 0.00400756 ... 0.00400756 0.00400756 0.00400756]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
# chi2/DOF: 0.04529; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
# chi2/DOF: 0.02502; DOF: 1908; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-39.20053928,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -281      1000
#  comp.  1:       -51        63
#  comp.  2:       -63        45
# chi2/DOF: 1.200; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.914      0.44     -51    63
# Comp:  1                Halpha      20.47      0.44     -51    63
# Comp:  2             [SII]6716      4.668      0.41     -63    45
# Comp:  2             [SII]6731      3.588      0.41     -63    45
# Comp:  2              HeII4687      0.000      0.41     -63    45
# Comp:  2               HeI5876     0.2282      0.41     -63    45
# Comp:  2          [OIII]5007_d      4.849      0.52     -63    45
# Comp:  2            [OI]6300_d      1.884      0.52     -63    45
# Comp:  2           [NII]6583_d      3.998      0.52     -63    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  7.951; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  32.87; gas flux:     28 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  8.104; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  6.536; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.4074; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   6.64; gas flux:      5 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.601; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  5.363; gas flux:      5 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -172       855
#  comp.  1:       -53        60
#  comp.  2:       -60        53
# chi2/DOF: 1.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.554      0.43     -53    60
# Comp:  1                Halpha      20.43      0.43     -53    60
# Comp:  2             [SII]6716      4.826      0.42     -60    53
# Comp:  2             [SII]6731      3.807      0.42     -60    53
# Comp:  2              HeII4687     0.1329      0.42     -60    53
# Comp:  2               HeI5876     0.2609      0.42     -60    53
# Comp:  2          [OIII]5007_d      5.361      0.53     -60    53
# Comp:  2            [OI]6300_d     0.8044      0.53     -60    53
# Comp:  2           [NII]6583_d      3.735      0.53     -60    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -870      1000
#  comp.  1:       -45        63
#  comp.  2:       -64        40
# chi2/DOF: 1.185; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.829      0.44     -45    63
# Comp:  1                Halpha      20.80      0.44     -45    63
# Comp:  2             [SII]6716      4.600      0.40     -64    40
# Comp:  2             [SII]6731      3.553      0.40     -64    40
# Comp:  2              HeII4687     0.6219      0.40     -64    40
# Comp:  2               HeI5876     0.4783      0.40     -64    40
# Comp:  2          [OIII]5007_d      4.678      0.51     -64    40
# Comp:  2            [OI]6300_d      1.929      0.51     -64    40
# Comp:  2           [NII]6583_d      4.065      0.51     -64    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -227      1000
#  comp.  1:       -49        66
#  comp.  2:       -67        51
# chi2/DOF: 1.194; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.069      0.44     -49    66
# Comp:  1                Halpha      20.94      0.44     -49    66
# Comp:  2             [SII]6716      4.763      0.42     -67    51
# Comp:  2             [SII]6731      3.549      0.42     -67    51
# Comp:  2              HeII4687    0.05894      0.42     -67    51
# Comp:  2               HeI5876     0.2672      0.42     -67    51
# Comp:  2          [OIII]5007_d      4.975      0.53     -67    51
# Comp:  2            [OI]6300_d      1.925      0.53     -67    51
# Comp:  2           [NII]6583_d      4.432      0.53     -67    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -563      1000
#  comp.  1:       -52        64
#  comp.  2:       -61        49
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.683      0.44     -52    64
# Comp:  1                Halpha      20.52      0.44     -52    64
# Comp:  2             [SII]6716      4.556      0.42     -61    49
# Comp:  2             [SII]6731      3.539      0.42     -61    49
# Comp:  2              HeII4687     0.3480      0.42     -61    49
# Comp:  2               HeI5876     0.2595      0.42     -61    49
# Comp:  2          [OIII]5007_d      4.685      0.52     -61    49
# Comp:  2            [OI]6300_d      1.787      0.52     -61    49
# Comp:  2           [NII]6583_d      4.333      0.52     -61    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        64       933
#  comp.  1:       -48        66
#  comp.  2:       -62        38
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.842      0.44     -48    66
# Comp:  1                Halpha      21.10      0.44     -48    66
# Comp:  2             [SII]6716      4.379      0.40     -62    38
# Comp:  2             [SII]6731      3.536      0.40     -62    38
# Comp:  2              HeII4687     0.1032      0.40     -62    38
# Comp:  2               HeI5876     0.2402      0.40     -62    38
# Comp:  2          [OIII]5007_d      4.584      0.51     -62    38
# Comp:  2            [OI]6300_d      1.871      0.51     -62    38
# Comp:  2           [NII]6583_d      4.288      0.51     -62    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -318      1000
#  comp.  1:       -50        64
#  comp.  2:       -60        44
# chi2/DOF: 1.188; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.351      0.44     -50    64
# Comp:  1                Halpha      20.34      0.44     -50    64
# Comp:  2             [SII]6716      4.440      0.41     -60    44
# Comp:  2             [SII]6731      3.347      0.41     -60    44
# Comp:  2              HeII4687      0.000      0.41     -60    44
# Comp:  2               HeI5876     0.2150      0.41     -60    44
# Comp:  2          [OIII]5007_d      4.844      0.52     -60    44
# Comp:  2            [OI]6300_d      1.560      0.52     -60    44
# Comp:  2           [NII]6583_d      3.456      0.52     -60    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -529       682
#  comp.  1:       -52        63
#  comp.  2:       -59        56
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.776      0.44     -52    63
# Comp:  1                Halpha      20.92      0.44     -52    63
# Comp:  2             [SII]6716      4.869      0.43     -59    56
# Comp:  2             [SII]6731      3.752      0.43     -59    56
# Comp:  2              HeII4687      0.000      0.43     -59    56
# Comp:  2               HeI5876     0.3061      0.43     -59    56
# Comp:  2          [OIII]5007_d      5.338      0.54     -59    56
# Comp:  2            [OI]6300_d      1.614      0.54     -59    56
# Comp:  2           [NII]6583_d      3.923      0.54     -59    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -257      1000
#  comp.  1:       -50        61
#  comp.  2:       -61        45
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.201      0.43     -50    61
# Comp:  1                Halpha      20.27      0.43     -50    61
# Comp:  2             [SII]6716      4.498      0.41     -61    45
# Comp:  2             [SII]6731      3.547      0.41     -61    45
# Comp:  2              HeII4687     0.5432      0.41     -61    45
# Comp:  2               HeI5876     0.2651      0.41     -61    45
# Comp:  2          [OIII]5007_d      4.788      0.52     -61    45
# Comp:  2            [OI]6300_d      1.387      0.52     -61    45
# Comp:  2           [NII]6583_d      3.800      0.52     -61    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -292      1000
#  comp.  1:       -49        68
#  comp.  2:       -67        44
# chi2/DOF: 1.196; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.118      0.45     -49    68
# Comp:  1                Halpha      21.38      0.45     -49    68
# Comp:  2             [SII]6716      4.635      0.41     -67    44
# Comp:  2             [SII]6731      3.685      0.41     -67    44
# Comp:  2              HeII4687     0.2143      0.41     -67    44
# Comp:  2               HeI5876    0.08720      0.41     -67    44
# Comp:  2          [OIII]5007_d      4.682      0.52     -67    44
# Comp:  2            [OI]6300_d      1.605      0.52     -67    44
# Comp:  2           [NII]6583_d      4.333      0.52     -67    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63      1000
#  comp.  1:       -56        61
#  comp.  2:       -61        41
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.943      0.44     -56    61
# Comp:  1                Halpha      20.02      0.44     -56    61
# Comp:  2             [SII]6716      4.529      0.40     -61    41
# Comp:  2             [SII]6731      3.411      0.40     -61    41
# Comp:  2              HeII4687      0.000      0.40     -61    41
# Comp:  2               HeI5876     0.1310      0.40     -61    41
# Comp:  2          [OIII]5007_d      4.741      0.51     -61    41
# Comp:  2            [OI]6300_d      1.823      0.51     -61    41
# Comp:  2           [NII]6583_d      3.623      0.51     -61    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160      1000
#  comp.  1:       -49        60
#  comp.  2:       -62        40
# chi2/DOF: 1.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.926      0.43     -49    60
# Comp:  1                Halpha      20.60      0.43     -49    60
# Comp:  2             [SII]6716      4.601      0.40     -62    40
# Comp:  2             [SII]6731      3.382      0.40     -62    40
# Comp:  2              HeII4687    0.03237      0.40     -62    40
# Comp:  2               HeI5876     0.1112      0.40     -62    40
# Comp:  2          [OIII]5007_d      4.819      0.51     -62    40
# Comp:  2            [OI]6300_d      2.334      0.51     -62    40
# Comp:  2           [NII]6583_d      4.298      0.51     -62    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -507      1000
#  comp.  1:       -47        63
#  comp.  2:       -62        44
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.832      0.44     -47    63
# Comp:  1                Halpha      21.12      0.44     -47    63
# Comp:  2             [SII]6716      4.461      0.41     -62    44
# Comp:  2             [SII]6731      3.350      0.41     -62    44
# Comp:  2              HeII4687      0.000      0.41     -62    44
# Comp:  2               HeI5876     0.3205      0.41     -62    44
# Comp:  2          [OIII]5007_d      4.868      0.52     -62    44
# Comp:  2            [OI]6300_d      1.181      0.52     -62    44
# Comp:  2           [NII]6583_d      3.826      0.52     -62    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -344      1000
#  comp.  1:       -54        61
#  comp.  2:       -58        55
# chi2/DOF: 1.187; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.458      0.43     -54    61
# Comp:  1                Halpha      20.05      0.43     -54    61
# Comp:  2             [SII]6716      4.796      0.42     -58    55
# Comp:  2             [SII]6731      3.744      0.42     -58    55
# Comp:  2              HeII4687      0.000      0.42     -58    55
# Comp:  2               HeI5876     0.5319      0.42     -58    55
# Comp:  2          [OIII]5007_d      5.301      0.54     -58    55
# Comp:  2            [OI]6300_d      2.146      0.54     -58    55
# Comp:  2           [NII]6583_d      4.541      0.54     -58    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111      1000
#  comp.  1:       -53        64
#  comp.  2:       -65        37
# chi2/DOF: 1.184; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.853      0.44     -53    64
# Comp:  1                Halpha      20.38      0.44     -53    64
# Comp:  2             [SII]6716      4.565      0.40     -65    37
# Comp:  2             [SII]6731      3.424      0.40     -65    37
# Comp:  2              HeII4687    0.08506      0.40     -65    37
# Comp:  2               HeI5876    0.01371      0.40     -65    37
# Comp:  2          [OIII]5007_d      4.337      0.50     -65    37
# Comp:  2            [OI]6300_d      1.573      0.50     -65    37
# Comp:  2           [NII]6583_d      3.830      0.50     -65    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -512       886
#  comp.  1:       -50        62
#  comp.  2:       -62        35
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.235      0.44     -50    62
# Comp:  1                Halpha      20.61      0.44     -50    62
# Comp:  2             [SII]6716      4.219      0.40     -62    35
# Comp:  2             [SII]6731      3.434      0.40     -62    35
# Comp:  2              HeII4687     0.1631      0.40     -62    35
# Comp:  2               HeI5876     0.3066      0.40     -62    35
# Comp:  2          [OIII]5007_d      4.483      0.50     -62    35
# Comp:  2            [OI]6300_d      2.485      0.50     -62    35
# Comp:  2           [NII]6583_d      3.709      0.50     -62    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24       978
#  comp.  1:       -50        65
#  comp.  2:       -64        46
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.567      0.44     -50    65
# Comp:  1                Halpha      20.96      0.44     -50    65
# Comp:  2             [SII]6716      4.506      0.41     -64    46
# Comp:  2             [SII]6731      3.586      0.41     -64    46
# Comp:  2              HeII4687     0.2563      0.41     -64    46
# Comp:  2               HeI5876     0.2553      0.41     -64    46
# Comp:  2          [OIII]5007_d      5.114      0.52     -64    46
# Comp:  2            [OI]6300_d      2.277      0.52     -64    46
# Comp:  2           [NII]6583_d      4.157      0.52     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22       314
#  comp.  1:       -50        60
#  comp.  2:       -58        54
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.856      0.43     -50    60
# Comp:  1                Halpha      20.93      0.43     -50    60
# Comp:  2             [SII]6716      4.726      0.42     -58    54
# Comp:  2             [SII]6731      3.607      0.42     -58    54
# Comp:  2              HeII4687     0.2387      0.42     -58    54
# Comp:  2               HeI5876     0.1796      0.42     -58    54
# Comp:  2          [OIII]5007_d      5.134      0.53     -58    54
# Comp:  2            [OI]6300_d      2.454      0.53     -58    54
# Comp:  2           [NII]6583_d      3.994      0.53     -58    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -681       917
#  comp.  1:       -49        65
#  comp.  2:       -59        42
# chi2/DOF: 1.181; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.070      0.44     -49    65
# Comp:  1                Halpha      20.90      0.44     -49    65
# Comp:  2             [SII]6716      4.597      0.41     -59    42
# Comp:  2             [SII]6731      3.540      0.41     -59    42
# Comp:  2              HeII4687      0.000      0.41     -59    42
# Comp:  2               HeI5876     0.3229      0.41     -59    42
# Comp:  2          [OIII]5007_d      4.791      0.51     -59    42
# Comp:  2            [OI]6300_d      1.925      0.51     -59    42
# Comp:  2           [NII]6583_d      4.111      0.51     -59    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -494       755
#  comp.  1:       -50        65
#  comp.  2:       -60        56
# chi2/DOF: 1.187; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.521      0.44     -50    65
# Comp:  1                Halpha      20.95      0.44     -50    65
# Comp:  2             [SII]6716      4.879      0.43     -60    56
# Comp:  2             [SII]6731      3.705      0.43     -60    56
# Comp:  2              HeII4687     0.4367      0.43     -60    56
# Comp:  2               HeI5876     0.2606      0.43     -60    56
# Comp:  2          [OIII]5007_d      5.228      0.54     -60    56
# Comp:  2            [OI]6300_d      1.372      0.54     -60    56
# Comp:  2           [NII]6583_d      4.211      0.54     -60    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -218      1000
#  comp.  1:       -50        65
#  comp.  2:       -58        52
# chi2/DOF: 1.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.540      0.44     -50    65
# Comp:  1                Halpha      20.78      0.44     -50    65
# Comp:  2             [SII]6716      4.982      0.42     -58    52
# Comp:  2             [SII]6731      3.686      0.42     -58    52
# Comp:  2              HeII4687     0.5776      0.42     -58    52
# Comp:  2               HeI5876     0.2485      0.42     -58    52
# Comp:  2          [OIII]5007_d      4.947      0.53     -58    52
# Comp:  2            [OI]6300_d      2.474      0.53     -58    52
# Comp:  2           [NII]6583_d      4.254      0.53     -58    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       466
#  comp.  1:       -48        64
#  comp.  2:       -56        49
# chi2/DOF: 1.184; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.801      0.44     -48    64
# Comp:  1                Halpha      21.07      0.44     -48    64
# Comp:  2             [SII]6716      4.647      0.42     -56    49
# Comp:  2             [SII]6731      3.570      0.42     -56    49
# Comp:  2              HeII4687      0.000      0.42     -56    49
# Comp:  2               HeI5876     0.3787      0.42     -56    49
# Comp:  2          [OIII]5007_d      4.857      0.53     -56    49
# Comp:  2            [OI]6300_d      1.339      0.53     -56    49
# Comp:  2           [NII]6583_d      3.996      0.53     -56    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -644      1000
#  comp.  1:       -48        59
#  comp.  2:       -65        46
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.840      0.43     -48    59
# Comp:  1                Halpha      20.42      0.43     -48    59
# Comp:  2             [SII]6716      4.687      0.41     -65    46
# Comp:  2             [SII]6731      3.688      0.41     -65    46
# Comp:  2              HeII4687      0.000      0.41     -65    46
# Comp:  2               HeI5876     0.1958      0.41     -65    46
# Comp:  2          [OIII]5007_d      4.875      0.52     -65    46
# Comp:  2            [OI]6300_d      1.547      0.52     -65    46
# Comp:  2           [NII]6583_d      3.965      0.52     -65    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -427      1000
#  comp.  1:       -54        66
#  comp.  2:       -62        45
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.023      0.44     -54    66
# Comp:  1                Halpha      20.49      0.44     -54    66
# Comp:  2             [SII]6716      4.599      0.41     -62    45
# Comp:  2             [SII]6731      3.575      0.41     -62    45
# Comp:  2              HeII4687     0.2006      0.41     -62    45
# Comp:  2               HeI5876     0.1972      0.41     -62    45
# Comp:  2          [OIII]5007_d      4.656      0.52     -62    45
# Comp:  2            [OI]6300_d      1.629      0.52     -62    45
# Comp:  2           [NII]6583_d      3.582      0.52     -62    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55       962
#  comp.  1:       -51        60
#  comp.  2:       -65        47
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.066      0.43     -51    60
# Comp:  1                Halpha      20.10      0.43     -51    60
# Comp:  2             [SII]6716      4.907      0.41     -65    47
# Comp:  2             [SII]6731      3.608      0.41     -65    47
# Comp:  2              HeII4687      0.000      0.41     -65    47
# Comp:  2               HeI5876     0.2626      0.41     -65    47
# Comp:  2          [OIII]5007_d      4.989      0.52     -65    47
# Comp:  2            [OI]6300_d      2.736      0.52     -65    47
# Comp:  2           [NII]6583_d      4.331      0.52     -65    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -500       993
#  comp.  1:       -52        59
#  comp.  2:       -59        46
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.708      0.43     -52    59
# Comp:  1                Halpha      20.14      0.43     -52    59
# Comp:  2             [SII]6716      4.724      0.41     -59    46
# Comp:  2             [SII]6731      3.607      0.41     -59    46
# Comp:  2              HeII4687      0.000      0.41     -59    46
# Comp:  2               HeI5876     0.1815      0.41     -59    46
# Comp:  2          [OIII]5007_d      5.118      0.52     -59    46
# Comp:  2            [OI]6300_d      2.089      0.52     -59    46
# Comp:  2           [NII]6583_d      3.657      0.52     -59    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -252      1000
#  comp.  1:       -47        63
#  comp.  2:       -67        43
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.783      0.44     -47    63
# Comp:  1                Halpha      20.62      0.44     -47    63
# Comp:  2             [SII]6716      4.779      0.41     -67    43
# Comp:  2             [SII]6731      3.563      0.41     -67    43
# Comp:  2              HeII4687      0.000      0.41     -67    43
# Comp:  2               HeI5876     0.1771      0.41     -67    43
# Comp:  2          [OIII]5007_d      4.648      0.51     -67    43
# Comp:  2            [OI]6300_d      1.619      0.51     -67    43
# Comp:  2           [NII]6583_d      4.041      0.51     -67    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -346       963
#  comp.  1:       -53        61
#  comp.  2:       -61        42
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.665      0.43     -53    61
# Comp:  1                Halpha      20.46      0.43     -53    61
# Comp:  2             [SII]6716      4.539      0.40     -61    42
# Comp:  2             [SII]6731      3.484      0.40     -61    42
# Comp:  2              HeII4687     0.6725      0.40     -61    42
# Comp:  2               HeI5876     0.1854      0.40     -61    42
# Comp:  2          [OIII]5007_d      4.661      0.51     -61    42
# Comp:  2            [OI]6300_d      1.585      0.51     -61    42
# Comp:  2           [NII]6583_d      4.218      0.51     -61    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       868
#  comp.  1:       -52        65
#  comp.  2:       -60        58
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.929      0.44     -52    65
# Comp:  1                Halpha      20.95      0.44     -52    65
# Comp:  2             [SII]6716      4.915      0.43     -60    58
# Comp:  2             [SII]6731      3.807      0.43     -60    58
# Comp:  2              HeII4687     0.2761      0.43     -60    58
# Comp:  2               HeI5876     0.4662      0.43     -60    58
# Comp:  2          [OIII]5007_d      5.273      0.54     -60    58
# Comp:  2            [OI]6300_d      2.426      0.54     -60    58
# Comp:  2           [NII]6583_d      4.713      0.54     -60    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138      1000
#  comp.  1:       -50        63
#  comp.  2:       -64        43
# chi2/DOF: 1.186; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.472      0.44     -50    63
# Comp:  1                Halpha      20.57      0.44     -50    63
# Comp:  2             [SII]6716      4.422      0.41     -64    43
# Comp:  2             [SII]6731      3.444      0.41     -64    43
# Comp:  2              HeII4687      0.000      0.41     -64    43
# Comp:  2               HeI5876     0.1176      0.41     -64    43
# Comp:  2          [OIII]5007_d      4.861      0.51     -64    43
# Comp:  2            [OI]6300_d      2.312      0.51     -64    43
# Comp:  2           [NII]6583_d      3.850      0.51     -64    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -760      1000
#  comp.  1:       -53        62
#  comp.  2:       -63        26
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.648      0.44     -53    62
# Comp:  1                Halpha      19.88      0.44     -53    62
# Comp:  2             [SII]6716      4.216      0.39     -63    26
# Comp:  2             [SII]6731      3.255      0.39     -63    26
# Comp:  2              HeII4687     0.2863      0.39     -63    26
# Comp:  2               HeI5876     0.2519      0.39     -63    26
# Comp:  2          [OIII]5007_d      4.357      0.49     -63    26
# Comp:  2            [OI]6300_d      2.063      0.49     -63    26
# Comp:  2           [NII]6583_d      3.363      0.49     -63    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -461      1000
#  comp.  1:       -51        65
#  comp.  2:       -56        47
# chi2/DOF: 1.188; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.606      0.44     -51    65
# Comp:  1                Halpha      20.24      0.44     -51    65
# Comp:  2             [SII]6716      4.446      0.41     -56    47
# Comp:  2             [SII]6731      3.670      0.41     -56    47
# Comp:  2              HeII4687      0.000      0.41     -56    47
# Comp:  2               HeI5876     0.2876      0.41     -56    47
# Comp:  2          [OIII]5007_d      5.107      0.52     -56    47
# Comp:  2            [OI]6300_d      1.893      0.52     -56    47
# Comp:  2           [NII]6583_d      4.333      0.52     -56    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       138       974
#  comp.  1:       -53        64
#  comp.  2:       -60        50
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.609      0.44     -53    64
# Comp:  1                Halpha      20.61      0.44     -53    64
# Comp:  2             [SII]6716      4.864      0.42     -60    50
# Comp:  2             [SII]6731      3.800      0.42     -60    50
# Comp:  2              HeII4687    0.03596      0.42     -60    50
# Comp:  2               HeI5876     0.2798      0.42     -60    50
# Comp:  2          [OIII]5007_d      4.759      0.53     -60    50
# Comp:  2            [OI]6300_d      2.705      0.53     -60    50
# Comp:  2           [NII]6583_d      4.895      0.53     -60    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       127      1000
#  comp.  1:       -48        64
#  comp.  2:       -65        38
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.598      0.44     -48    64
# Comp:  1                Halpha      20.95      0.44     -48    64
# Comp:  2             [SII]6716      4.335      0.40     -65    38
# Comp:  2             [SII]6731      3.484      0.40     -65    38
# Comp:  2              HeII4687     0.1915      0.40     -65    38
# Comp:  2               HeI5876     0.3479      0.40     -65    38
# Comp:  2          [OIII]5007_d      4.955      0.51     -65    38
# Comp:  2            [OI]6300_d      2.238      0.51     -65    38
# Comp:  2           [NII]6583_d      3.531      0.51     -65    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -295      1000
#  comp.  1:       -48        66
#  comp.  2:       -57        54
# chi2/DOF: 1.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.246      0.44     -48    66
# Comp:  1                Halpha      20.90      0.44     -48    66
# Comp:  2             [SII]6716      4.936      0.42     -57    54
# Comp:  2             [SII]6731      3.770      0.42     -57    54
# Comp:  2              HeII4687      0.000      0.42     -57    54
# Comp:  2               HeI5876     0.2832      0.42     -57    54
# Comp:  2          [OIII]5007_d      5.387      0.53     -57    54
# Comp:  2            [OI]6300_d      1.307      0.53     -57    54
# Comp:  2           [NII]6583_d      4.812      0.53     -57    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -533      1000
#  comp.  1:       -52        67
#  comp.  2:       -60        39
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.285      0.44     -52    67
# Comp:  1                Halpha      21.18      0.44     -52    67
# Comp:  2             [SII]6716      4.455      0.40     -60    39
# Comp:  2             [SII]6731      3.343      0.40     -60    39
# Comp:  2              HeII4687     0.1744      0.40     -60    39
# Comp:  2               HeI5876     0.3732      0.40     -60    39
# Comp:  2          [OIII]5007_d      4.587      0.51     -60    39
# Comp:  2            [OI]6300_d      2.251      0.51     -60    39
# Comp:  2           [NII]6583_d      4.351      0.51     -60    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65      1000
#  comp.  1:       -49        63
#  comp.  2:       -64        45
# chi2/DOF: 1.190; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.957      0.44     -49    63
# Comp:  1                Halpha      20.93      0.44     -49    63
# Comp:  2             [SII]6716      4.619      0.41     -64    45
# Comp:  2             [SII]6731      3.794      0.41     -64    45
# Comp:  2              HeII4687     0.1264      0.41     -64    45
# Comp:  2               HeI5876     0.3390      0.41     -64    45
# Comp:  2          [OIII]5007_d      4.641      0.52     -64    45
# Comp:  2            [OI]6300_d      1.351      0.52     -64    45
# Comp:  2           [NII]6583_d      3.652      0.52     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -382      1000
#  comp.  1:       -49        67
#  comp.  2:       -58        43
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.855      0.44     -49    67
# Comp:  1                Halpha      21.06      0.44     -49    67
# Comp:  2             [SII]6716      4.690      0.41     -58    43
# Comp:  2             [SII]6731      3.722      0.41     -58    43
# Comp:  2              HeII4687      0.000      0.41     -58    43
# Comp:  2               HeI5876     0.1258      0.41     -58    43
# Comp:  2          [OIII]5007_d      4.893      0.51     -58    43
# Comp:  2            [OI]6300_d      1.292      0.51     -58    43
# Comp:  2           [NII]6583_d      3.734      0.51     -58    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -482      1000
#  comp.  1:       -49        61
#  comp.  2:       -61        43
# chi2/DOF: 1.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.848      0.43     -49    61
# Comp:  1                Halpha      20.25      0.43     -49    61
# Comp:  2             [SII]6716      4.656      0.41     -61    43
# Comp:  2             [SII]6731      3.714      0.41     -61    43
# Comp:  2              HeII4687    0.01314      0.41     -61    43
# Comp:  2               HeI5876    0.07524      0.41     -61    43
# Comp:  2          [OIII]5007_d      4.580      0.51     -61    43
# Comp:  2            [OI]6300_d      1.987      0.51     -61    43
# Comp:  2           [NII]6583_d      3.682      0.51     -61    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -422       939
#  comp.  1:       -48        63
#  comp.  2:       -59        52
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.075      0.44     -48    63
# Comp:  1                Halpha      20.42      0.44     -48    63
# Comp:  2             [SII]6716      4.881      0.42     -59    52
# Comp:  2             [SII]6731      3.742      0.42     -59    52
# Comp:  2              HeII4687      0.000      0.42     -59    52
# Comp:  2               HeI5876     0.2796      0.42     -59    52
# Comp:  2          [OIII]5007_d      5.044      0.53     -59    52
# Comp:  2            [OI]6300_d      1.806      0.53     -59    52
# Comp:  2           [NII]6583_d      4.360      0.53     -59    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1324       863
#  comp.  1:       -53        57
#  comp.  2:       -61        45
# chi2/DOF: 1.181; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.922      0.43     -53    57
# Comp:  1                Halpha      19.66      0.43     -53    57
# Comp:  2             [SII]6716      4.380      0.41     -61    45
# Comp:  2             [SII]6731      3.346      0.41     -61    45
# Comp:  2              HeII4687    0.06414      0.41     -61    45
# Comp:  2               HeI5876     0.2568      0.41     -61    45
# Comp:  2          [OIII]5007_d      5.108      0.52     -61    45
# Comp:  2            [OI]6300_d      1.474      0.52     -61    45
# Comp:  2           [NII]6583_d      3.774      0.52     -61    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -211       732
#  comp.  1:       -52        62
#  comp.  2:       -63        46
# chi2/DOF: 1.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.923      0.44     -52    62
# Comp:  1                Halpha      20.43      0.44     -52    62
# Comp:  2             [SII]6716      4.824      0.41     -63    46
# Comp:  2             [SII]6731      3.439      0.41     -63    46
# Comp:  2              HeII4687      0.000      0.41     -63    46
# Comp:  2               HeI5876     0.2890      0.41     -63    46
# Comp:  2          [OIII]5007_d      4.958      0.52     -63    46
# Comp:  2            [OI]6300_d      2.103      0.52     -63    46
# Comp:  2           [NII]6583_d      4.173      0.52     -63    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1241         1
#  comp.  1:       -48        63
#  comp.  2:       -62        38
# chi2/DOF: 1.181; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.756      0.44     -48    63
# Comp:  1                Halpha      20.60      0.44     -48    63
# Comp:  2             [SII]6716      4.663      0.40     -62    38
# Comp:  2             [SII]6731      3.475      0.40     -62    38
# Comp:  2              HeII4687      0.000      0.40     -62    38
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.993      0.44     -49    66
# Comp:  1                Halpha      20.79      0.44     -49    66
# Comp:  2             [SII]6716      4.856      0.41     -64    46
# Comp:  2             [SII]6731      3.667      0.41     -64    46
# Comp:  2              HeII4687      0.000      0.41     -64    46
# Comp:  2               HeI5876     0.3106      0.41     -64    46
# Comp:  2          [OIII]5007_d      4.521      0.52     -64    46
# Comp:  2            [OI]6300_d      1.513      0.52     -64    46
# Comp:  2           [NII]6583_d      4.331      0.52     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38      1000
#  comp.  1:       -51        64
#  comp.  2:       -62        40
# chi2/DOF: 1.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.551      0.44     -51    64
# Comp:  1                Halpha      20.26      0.44     -51    64
# Comp:  2             [SII]6716      4.420      0.40     -62    40
# Comp:  2             [SII]6731      3.427      0.40     -62    40
# Comp:  2              HeII4687     0.5741      0.40     -62    40
# Comp:  2               HeI5876     0.2904      0.40     -62    40
# Comp:  2          [OIII]5007_d      4.732      0.51     -62    40
# Comp:  2            [OI]6300_d      2.168      0.51     -62    40
# Comp:  2           [NII]6583_d      3.870      0.51     -62    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11      1000
#  comp.  1:       -47        66
#  comp.  2:       -64        45
# chi2/DOF: 1.192; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.887      0.44     -47    66
# Comp:  1                Halpha      21.23      0.44     -47    66
# Comp:  2             [SII]6716      4.652      0.41     -64    45
# Comp:  2             [SII]6731      3.637      0.41     -64    45
# Comp:  2              HeII4687      0.000      0.41     -64    45
# Comp:  2               HeI5876     0.4588      0.41     -64    45
# Comp:  2          [OIII]5007_d      4.795      0.52     -64    45
# Comp:  2            [OI]6300_d      2.308      0.52     -64    45
# Comp:  2           [NII]6583_d      3.784      0.52     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -190       964
#  comp.  1:       -56        65
#  comp.  2:       -59        51
# chi2/DOF: 1.194; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.591      0.44     -56    65
# Comp:  1                Halpha      20.47      0.44     -56    65
# Comp:  2             [SII]6716      4.829      0.42     -59    51
# Comp:  2             [SII]6731      3.778      0.42     -59    51
# Comp:  2              HeII4687     0.6308      0.42     -59    51
# Comp:  2               HeI5876     0.2326      0.42     -59    51
# Comp:  2          [OIII]5007_d      5.094      0.53     -59    51
# Comp:  2            [OI]6300_d      1.377      0.53     -59    51
# Comp:  2           [NII]6583_d      4.398      0.53     -59    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -477      1000
#  comp.  1:       -50        59
#  comp.  2:       -61        46
# chi2/DOF: 1.185; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.899      0.43     -50    59
# Comp:  1                Halpha      20.69      0.43     -50    59
# Comp:  2             [SII]6716      4.485      0.41     -61    46
# Comp:  2             [SII]6731      3.624      0.41     -61    46
# Comp:  2              HeII4687     0.4604      0.41     -61    46
# Comp:  2               HeI5876     0.3986      0.41     -61    46
# Comp:  2          [OIII]5007_d      5.230      0.52     -61    46
# Comp:  2            [OI]6300_d      1.745      0.52     -61    46
# Comp:  2           [NII]6583_d      3.495      0.52     -61    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -258       592
#  comp.  1:       -52        61
#  comp.  2:       -68        38
# chi2/DOF: 1.186; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.144      0.43     -52    61
# Comp:  1                Halpha      20.30      0.43     -52    61
# Comp:  2             [SII]6716      4.597      0.40     -68    38
# Comp:  2             [SII]6731      3.683      0.40     -68    38
# Comp:  2              HeII4687      0.000      0.40     -68    38
# Comp:  2               HeI5876     0.2815      0.40     -68    38
# Comp:  2          [OIII]5007_d      4.766      0.50     -68    38
# Comp:  2            [OI]6300_d      1.543      0.50     -68    38
# Comp:  2           [NII]6583_d      3.652      0.50     -68    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7      1000
#  comp.  1:       -52        62
#  comp.  2:       -64        50
# chi2/DOF: 1.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.433      0.44     -52    62
# Comp:  1                Halpha      20.73      0.44     -52    62
# Comp:  2             [SII]6716      4.653      0.42     -64    50
# Comp:  2             [SII]6731      3.674      0.42     -64    50
# Comp:  2              HeII4687     0.5158      0.42     -64    50
# Comp:  2               HeI5876     0.3145      0.42     -64    50
# Comp:  2          [OIII]5007_d      5.198      0.53     -64    50
# Comp:  2            [OI]6300_d      1.301      0.53     -64    50
# Comp:  2           [NII]6583_d      4.505      0.53     -64    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -282      1000
#  comp.  1:       -49        66
#  comp.  2:       -61        53
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.520      0.44     -49    66
# Comp:  1                Halpha      21.20      0.44     -49    66
# Comp:  2             [SII]6716      4.915      0.42     -61    53
# Comp:  2             [SII]6731      3.554      0.42     -61    53
# Comp:  2              HeII4687     0.1873      0.42     -61    53
# Comp:  2               HeI5876     0.1037      0.42     -61    53
# Comp:  2          [OIII]5007_d      5.194      0.53     -61    53
# Comp:  2            [OI]6300_d      1.618      0.53     -61    53
# Comp:  2           [NII]6583_d      4.140      0.53     -61    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60      1000
#  comp.  1:       -55        62
#  comp.  2:       -60        45
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.181      0.44     -55    62
# Comp:  1                Halpha      20.46      0.44     -55    62
# Comp:  2             [SII]6716      4.809      0.41     -60    45
# Comp:  2             [SII]6731      3.416      0.41     -60    45
# Comp:  2              HeII4687    0.03063      0.41     -60    45
# Comp:  2               HeI5876     0.4406      0.41     -60    45
# Comp:  2          [OIII]5007_d      4.909      0.52     -60    45
# Comp:  2            [OI]6300_d      2.569      0.52     -60    45
# Comp:  2           [NII]6583_d      4.242      0.52     -60    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -688      1000
#  comp.  1:       -48        65
#  comp.  2:       -62        38
# chi2/DOF: 1.185; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.635      0.44     -48    65
# Comp:  1                Halpha      21.01      0.44     -48    65
# Comp:  2             [SII]6716      4.440      0.40     -62    38
# Comp:  2             [SII]6731      3.496      0.40     -62    38
# Comp:  2              HeII4687      0.000      0.40     -62    38
# Comp:  2               HeI5876     0.4378      0.40     -62    38
# Comp:  2          [OIII]5007_d      4.816      0.51     -62    38
# Comp:  2            [OI]6300_d      2.619      0.51     -62    38
# Comp:  2           [NII]6583_d      3.767      0.51     -62    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       905
#  comp.  1:       -53        66
#  comp.  2:       -62        42
# chi2/DOF: 1.191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.532      0.44     -53    66
# Comp:  1                Halpha      20.61      0.44     -53    66
# Comp:  2             [SII]6716      4.637      0.40     -62    42
# Comp:  2             [SII]6731      3.543      0.40     -62    42
# Comp:  2              HeII4687      0.000      0.40     -62    42
# Comp:  2               HeI5876     0.2659      0.40     -62    42
# Comp:  2          [OIII]5007_d      4.544      0.51     -62    42
# Comp:  2            [OI]6300_d      2.298      0.51     -62    42
# Comp:  2           [NII]6583_d      4.084      0.51     -62    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -244       920
#  comp.  1:       -49        65
#  comp.  2:       -61        39
# chi2/DOF: 1.193; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.742      0.44     -49    65
# Comp:  1                Halpha      21.20      0.44     -49    65
# Comp:  2             [SII]6716      4.488      0.40     -61    39
# Comp:  2             [SII]6731      3.458      0.40     -61    39
# Comp:  2              HeII4687     0.5113      0.40     -61    39
# Comp:  2               HeI5876     0.2259      0.40     -61    39
# Comp:  2          [OIII]5007_d      4.641      0.51     -61    39
# Comp:  2            [OI]6300_d      1.716      0.51     -61    39
# Comp:  2           [NII]6583_d      3.436      0.51     -61    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -244      1000
#  comp.  1:       -50        63
#  comp.  2:       -71        44
# chi2/DOF: 1.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.815      0.44     -50    63
# Comp:  1                Halpha      20.43      0.44     -50    63
# Comp:  2             [SII]6716      4.620      0.41     -71    44
# Comp:  2             [SII]6731      3.527      0.41     -71    44
# Comp:  2              HeII4687    0.02986      0.41     -71    44
# Comp:  2               HeI5876     0.2321      0.41     -71    44
# Comp:  2          [OIII]5007_d      4.693      0.51     -71    44
# Comp:  2            [OI]6300_d      1.942      0.51     -71    44
# Comp:  2           [NII]6583_d      4.000      0.51     -71    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -194      1000
#  comp.  1:       -50        61
#  comp.  2:       -67        42
# chi2/DOF: 1.188; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.301      0.43     -50    61
# Comp:  1                Halpha      20.63      0.43     -50    61
# Comp:  2             [SII]6716      4.757      0.40     -67    42
# Comp:  2             [SII]6731      3.529      0.40     -67    42
# Comp:  2              HeII4687      0.000      0.40     -67    42
# Comp:  2               HeI5876     0.1212      0.40     -67    42
# Comp:  2          [OIII]5007_d      4.956      0.51     -67    42
# Comp:  2            [OI]6300_d      1.466      0.51     -67    42
# Comp:  2           [NII]6583_d      3.343      0.51     -67    42
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.67674228, 0.50921834, 0.23911256, 0.21537984, 0.20464891,
#        0.12115546, 0.30242384, 0.63689034, 0.4131219 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.98216078, 28.02650991,  6.539419  ,  5.03733587,  0.        ,
#         0.27965528,  5.06364244,  2.47565266,  5.49043268])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_2_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_2_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_2_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.103850    0.014106
# 1        Halpha  0.584196    0.010614
# 2     [SII]6716  0.136310    0.004984
# 3     [SII]6731  0.105000    0.004489
# 4      HeII4687  0.000000    0.004266
# 5       HeI5876  0.005829    0.002525
# 6  [OIII]5007_d  0.105549    0.006304
# 7    [OI]6300_d  0.051604    0.013276
# 8   [NII]6583_d  0.114445    0.008611
#           Name      Flux  Error_flux
# 0        Hbeta  0.103850    0.014106
# 1       Halpha  0.584196    0.010614
# 2    [SII]6716  0.136310    0.004984
# 3    [SII]6731  0.105000    0.004489
# 4     HeII4687  0.000000    0.004266
# 5      HeI5876  0.005829    0.002525
# 6   [OIII]4959  0.026387    0.006304
# 7   [OIII]5007  0.079161    0.006304
# 8     [OI]6300  0.038703    0.013276
# 9     [OI]6364  0.012901    0.013276
# 10   [NII]6548  0.028611    0.008611
# 11   [NII]6583  0.085834    0.008611

# %%
np.median(flux_rf_rebin)
# Out:
# 0.020844402586047254
