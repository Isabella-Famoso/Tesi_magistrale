# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = 0.00189
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4444.779367   4446.25657507 4447.73378315 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.09831984 0.08220544 0.07496981 ... 0.04652633 0.04799674 0.04996026] [0.0100189 0.0100189 0.0100189 ... 0.0100189 0.0100189 0.0100189]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
# chi2/DOF: 0.02923; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
# chi2/DOF: 0.01179; DOF: 1918; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-54.26600001,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -53        54
#  comp.  2:       -65        45
# chi2/DOF: 0.9714; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.280      0.37     -53    54
# Comp:  1                Halpha      15.80      0.37     -53    54
# Comp:  2             [SII]6716      3.944      0.36     -65    45
# Comp:  2             [SII]6731      2.984      0.36     -65    45
# Comp:  2              HeII4687      0.000      0.36     -65    45
# Comp:  2               HeI5876      0.000      0.36     -65    45
# Comp:  2          [OIII]5007_d      4.518      0.45     -65    45
# Comp:  2            [OI]6300_d      1.429      0.45     -65    45
# Comp:  2           [NII]6583_d      2.946      0.45     -65    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  13.93; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  41.18; gas flux:     22 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  10.45; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  8.337; gas flux:      4 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  9.559; gas flux:      5 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.032; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  6.046; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        38
#  comp.  1:       -54        54
#  comp.  2:       -64        45
# chi2/DOF: 0.9648; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.491      0.37     -54    54
# Comp:  1                Halpha      16.16      0.37     -54    54
# Comp:  2             [SII]6716      3.948      0.36     -64    45
# Comp:  2             [SII]6731      2.992      0.36     -64    45
# Comp:  2              HeII4687      0.000      0.36     -64    45
# Comp:  2               HeI5876     0.2255      0.36     -64    45
# Comp:  2          [OIII]5007_d      4.716      0.45     -64    45
# Comp:  2            [OI]6300_d     0.9917      0.45     -64    45
# Comp:  2           [NII]6583_d      2.715      0.45     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -50        54
#  comp.  2:       -62        44
# chi2/DOF: 0.9676; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.117      0.37     -50    54
# Comp:  1                Halpha      16.32      0.37     -50    54
# Comp:  2             [SII]6716      3.937      0.35     -62    44
# Comp:  2             [SII]6731      3.022      0.35     -62    44
# Comp:  2              HeII4687      0.000      0.35     -62    44
# Comp:  2               HeI5876    0.07740      0.35     -62    44
# Comp:  2          [OIII]5007_d      4.309      0.45     -62    44
# Comp:  2            [OI]6300_d      1.342      0.45     -62    44
# Comp:  2           [NII]6583_d      2.865      0.45     -62    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        34
#  comp.  1:       -54        58
#  comp.  2:       -72        46
# chi2/DOF: 0.9648; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.052      0.37     -54    58
# Comp:  1                Halpha      16.14      0.37     -54    58
# Comp:  2             [SII]6716      3.900      0.36     -72    46
# Comp:  2             [SII]6731      2.762      0.36     -72    46
# Comp:  2              HeII4687      0.000      0.36     -72    46
# Comp:  2               HeI5876      0.000      0.36     -72    46
# Comp:  2          [OIII]5007_d      4.575      0.45     -72    46
# Comp:  2            [OI]6300_d      1.414      0.45     -72    46
# Comp:  2           [NII]6583_d      3.308      0.45     -72    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -54        54
#  comp.  2:       -63        37
# chi2/DOF: 0.9604; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.154      0.37     -54    54
# Comp:  1                Halpha      16.15      0.37     -54    54
# Comp:  2             [SII]6716      3.816      0.35     -63    37
# Comp:  2             [SII]6731      2.643      0.35     -63    37
# Comp:  2              HeII4687     0.1443      0.35     -63    37
# Comp:  2               HeI5876    0.03165      0.35     -63    37
# Comp:  2          [OIII]5007_d      4.575      0.44     -63    37
# Comp:  2            [OI]6300_d      1.325      0.44     -63    37
# Comp:  2           [NII]6583_d      3.098      0.44     -63    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        54
#  comp.  1:       -53        55
#  comp.  2:       -64        44
# chi2/DOF: 0.9613; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.324      0.37     -53    55
# Comp:  1                Halpha      15.84      0.37     -53    55
# Comp:  2             [SII]6716      3.833      0.35     -64    44
# Comp:  2             [SII]6731      3.132      0.35     -64    44
# Comp:  2              HeII4687    0.03152      0.35     -64    44
# Comp:  2               HeI5876    0.08994      0.35     -64    44
# Comp:  2          [OIII]5007_d      4.297      0.45     -64    44
# Comp:  2            [OI]6300_d      1.254      0.45     -64    44
# Comp:  2           [NII]6583_d      2.945      0.45     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        57
#  comp.  1:       -53        52
#  comp.  2:       -59        46
# chi2/DOF: 0.9614; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.054      0.37     -53    52
# Comp:  1                Halpha      16.08      0.37     -53    52
# Comp:  2             [SII]6716      3.843      0.36     -59    46
# Comp:  2             [SII]6731      2.696      0.36     -59    46
# Comp:  2              HeII4687      0.000      0.36     -59    46
# Comp:  2               HeI5876     0.1583      0.36     -59    46
# Comp:  2          [OIII]5007_d      4.537      0.45     -59    46
# Comp:  2            [OI]6300_d      1.419      0.45     -59    46
# Comp:  2           [NII]6583_d      2.578      0.45     -59    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        83
#  comp.  1:       -54        56
#  comp.  2:       -62        50
# chi2/DOF: 0.9634; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.747      0.37     -54    56
# Comp:  1                Halpha      16.21      0.37     -54    56
# Comp:  2             [SII]6716      4.002      0.36     -62    50
# Comp:  2             [SII]6731      3.241      0.36     -62    50
# Comp:  2              HeII4687     0.1229      0.36     -62    50
# Comp:  2               HeI5876      0.000      0.36     -62    50
# Comp:  2          [OIII]5007_d      4.541      0.46     -62    50
# Comp:  2            [OI]6300_d      1.133      0.46     -62    50
# Comp:  2           [NII]6583_d      2.836      0.46     -62    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -55        51
#  comp.  2:       -63        48
# chi2/DOF: 0.9645; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.567      0.36     -55    51
# Comp:  1                Halpha      15.87      0.36     -55    51
# Comp:  2             [SII]6716      3.900      0.36     -63    48
# Comp:  2             [SII]6731      3.077      0.36     -63    48
# Comp:  2              HeII4687      0.000      0.36     -63    48
# Comp:  2               HeI5876      0.000      0.36     -63    48
# Comp:  2          [OIII]5007_d      4.456      0.45     -63    48
# Comp:  2            [OI]6300_d      1.244      0.45     -63    48
# Comp:  2           [NII]6583_d      2.773      0.45     -63    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        35
#  comp.  1:       -53        55
#  comp.  2:       -64        44
# chi2/DOF: 0.9671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.828      0.37     -53    55
# Comp:  1                Halpha      15.92      0.37     -53    55
# Comp:  2             [SII]6716      3.870      0.35     -64    44
# Comp:  2             [SII]6731      3.113      0.35     -64    44
# Comp:  2              HeII4687     0.1819      0.35     -64    44
# Comp:  2               HeI5876      0.000      0.35     -64    44
# Comp:  2          [OIII]5007_d      4.071      0.45     -64    44
# Comp:  2            [OI]6300_d      1.278      0.45     -64    44
# Comp:  2           [NII]6583_d      3.017      0.45     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        31
#  comp.  1:       -56        56
#  comp.  2:       -60        41
# chi2/DOF: 0.9660; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.837      0.37     -56    56
# Comp:  1                Halpha      15.57      0.37     -56    56
# Comp:  2             [SII]6716      3.852      0.35     -60    41
# Comp:  2             [SII]6731      2.687      0.35     -60    41
# Comp:  2              HeII4687      0.000      0.35     -60    41
# Comp:  2               HeI5876      0.000      0.35     -60    41
# Comp:  2          [OIII]5007_d      4.396      0.44     -60    41
# Comp:  2            [OI]6300_d      1.273      0.44     -60    41
# Comp:  2           [NII]6583_d      2.661      0.44     -60    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        86
#  comp.  1:       -52        52
#  comp.  2:       -64        46
# chi2/DOF: 0.9646; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.584      0.36     -52    52
# Comp:  1                Halpha      16.23      0.36     -52    52
# Comp:  2             [SII]6716      3.984      0.36     -64    46
# Comp:  2             [SII]6731      2.990      0.36     -64    46
# Comp:  2              HeII4687      0.000      0.36     -64    46
# Comp:  2               HeI5876     0.2647      0.36     -64    46
# Comp:  2          [OIII]5007_d      4.429      0.45     -64    46
# Comp:  2            [OI]6300_d      1.494      0.45     -64    46
# Comp:  2           [NII]6583_d      3.098      0.45     -64    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        50
#  comp.  1:       -52        55
#  comp.  2:       -66        46
# chi2/DOF: 0.9669; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.014      0.37     -52    55
# Comp:  1                Halpha      16.19      0.37     -52    55
# Comp:  2             [SII]6716      3.886      0.36     -66    46
# Comp:  2             [SII]6731      2.818      0.36     -66    46
# Comp:  2              HeII4687      0.000      0.36     -66    46
# Comp:  2               HeI5876      0.000      0.36     -66    46
# Comp:  2          [OIII]5007_d      4.381      0.45     -66    46
# Comp:  2            [OI]6300_d      1.311      0.45     -66    46
# Comp:  2           [NII]6583_d      2.734      0.45     -66    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -54        57
#  comp.  2:       -64        53
# chi2/DOF: 0.9583; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.202      0.37     -54    57
# Comp:  1                Halpha      15.92      0.37     -54    57
# Comp:  2             [SII]6716      4.072      0.37     -64    53
# Comp:  2             [SII]6731      3.344      0.37     -64    53
# Comp:  2              HeII4687      0.000      0.37     -64    53
# Comp:  2               HeI5876     0.2771      0.37     -64    53
# Comp:  2          [OIII]5007_d      5.412      0.46     -64    53
# Comp:  2            [OI]6300_d      1.602      0.46     -64    53
# Comp:  2           [NII]6583_d      3.291      0.46     -64    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        46
#  comp.  1:       -55        56
#  comp.  2:       -65        42
# chi2/DOF: 0.9618; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.697      0.37     -55    56
# Comp:  1                Halpha      16.15      0.37     -55    56
# Comp:  2             [SII]6716      3.946      0.35     -65    42
# Comp:  2             [SII]6731      3.035      0.35     -65    42
# Comp:  2              HeII4687      0.000      0.35     -65    42
# Comp:  2               HeI5876      0.000      0.35     -65    42
# Comp:  2          [OIII]5007_d      4.061      0.44     -65    42
# Comp:  2            [OI]6300_d      1.376      0.44     -65    42
# Comp:  2           [NII]6583_d      2.772      0.44     -65    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        34
#  comp.  1:       -54        55
#  comp.  2:       -63        39
# chi2/DOF: 0.9638; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.510      0.37     -54    55
# Comp:  1                Halpha      15.90      0.37     -54    55
# Comp:  2             [SII]6716      3.700      0.35     -63    39
# Comp:  2             [SII]6731      2.884      0.35     -63    39
# Comp:  2              HeII4687      0.000      0.35     -63    39
# Comp:  2               HeI5876      0.000      0.35     -63    39
# Comp:  2          [OIII]5007_d      4.390      0.44     -63    39
# Comp:  2            [OI]6300_d      1.626      0.44     -63    39
# Comp:  2           [NII]6583_d      3.077      0.44     -63    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        39
#  comp.  1:       -54        57
#  comp.  2:       -67        47
# chi2/DOF: 0.9666; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.209      0.37     -54    57
# Comp:  1                Halpha      16.05      0.37     -54    57
# Comp:  2             [SII]6716      3.903      0.36     -67    47
# Comp:  2             [SII]6731      3.046      0.36     -67    47
# Comp:  2              HeII4687      0.000      0.36     -67    47
# Comp:  2               HeI5876      0.000      0.36     -67    47
# Comp:  2          [OIII]5007_d      5.169      0.45     -67    47
# Comp:  2            [OI]6300_d      1.697      0.45     -67    47
# Comp:  2           [NII]6583_d      3.069      0.45     -67    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       117
#  comp.  1:       -55        55
#  comp.  2:       -61        45
# chi2/DOF: 0.9660; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.623      0.37     -55    55
# Comp:  1                Halpha      16.37      0.37     -55    55
# Comp:  2             [SII]6716      3.885      0.36     -61    45
# Comp:  2             [SII]6731      2.770      0.36     -61    45
# Comp:  2              HeII4687     0.1249      0.36     -61    45
# Comp:  2               HeI5876      0.000      0.36     -61    45
# Comp:  2          [OIII]5007_d      4.487      0.45     -61    45
# Comp:  2            [OI]6300_d      1.641      0.45     -61    45
# Comp:  2           [NII]6583_d      3.090      0.45     -61    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -51        57
#  comp.  2:       -64        44
# chi2/DOF: 0.9600; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.435      0.37     -51    57
# Comp:  1                Halpha      16.07      0.37     -51    57
# Comp:  2             [SII]6716      3.898      0.35     -64    44
# Comp:  2             [SII]6731      2.817      0.35     -64    44
# Comp:  2              HeII4687      0.000      0.35     -64    44
# Comp:  2               HeI5876      0.000      0.35     -64    44
# Comp:  2          [OIII]5007_d      3.953      0.45     -64    44
# Comp:  2            [OI]6300_d      1.265      0.45     -64    44
# Comp:  2           [NII]6583_d      2.791      0.45     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:       -53        57
#  comp.  2:       -61        49
# chi2/DOF: 0.9621; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.125      0.37     -53    57
# Comp:  1                Halpha      16.03      0.37     -53    57
# Comp:  2             [SII]6716      3.919      0.36     -61    49
# Comp:  2             [SII]6731      2.910      0.36     -61    49
# Comp:  2              HeII4687     0.1579      0.36     -61    49
# Comp:  2               HeI5876      0.000      0.36     -61    49
# Comp:  2          [OIII]5007_d      4.395      0.46     -61    49
# Comp:  2            [OI]6300_d      1.139      0.46     -61    49
# Comp:  2           [NII]6583_d      2.953      0.46     -61    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        36
#  comp.  1:       -53        58
#  comp.  2:       -63        50
# chi2/DOF: 0.9637; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.635      0.37     -53    58
# Comp:  1                Halpha      15.85      0.37     -53    58
# Comp:  2             [SII]6716      4.118      0.36     -63    50
# Comp:  2             [SII]6731      3.126      0.36     -63    50
# Comp:  2              HeII4687     0.1824      0.36     -63    50
# Comp:  2               HeI5876      0.000      0.36     -63    50
# Comp:  2          [OIII]5007_d      5.051      0.46     -63    50
# Comp:  2            [OI]6300_d      1.741      0.46     -63    50
# Comp:  2           [NII]6583_d      3.066      0.46     -63    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        12
#  comp.  1:       -51        54
#  comp.  2:       -59        46
# chi2/DOF: 0.9653; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.742      0.37     -51    54
# Comp:  1                Halpha      16.31      0.37     -51    54
# Comp:  2             [SII]6716      3.942      0.36     -59    46
# Comp:  2             [SII]6731      3.048      0.36     -59    46
# Comp:  2              HeII4687      0.000      0.36     -59    46
# Comp:  2               HeI5876    0.08649      0.36     -59    46
# Comp:  2          [OIII]5007_d      4.658      0.45     -59    46
# Comp:  2            [OI]6300_d      1.130      0.45     -59    46
# Comp:  2           [NII]6583_d      3.068      0.45     -59    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        74
#  comp.  1:       -53        52
#  comp.  2:       -67        49
# chi2/DOF: 0.9632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.506      0.36     -53    52
# Comp:  1                Halpha      16.00      0.36     -53    52
# Comp:  2             [SII]6716      4.001      0.36     -67    49
# Comp:  2             [SII]6731      3.073      0.36     -67    49
# Comp:  2              HeII4687      0.000      0.36     -67    49
# Comp:  2               HeI5876     0.2730      0.36     -67    49
# Comp:  2          [OIII]5007_d      4.754      0.46     -67    49
# Comp:  2            [OI]6300_d      1.349      0.46     -67    49
# Comp:  2           [NII]6583_d      3.255      0.46     -67    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        29
#  comp.  1:       -54        59
#  comp.  2:       -63        39
# chi2/DOF: 0.9641; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.974      0.37     -54    59
# Comp:  1                Halpha      15.80      0.37     -54    59
# Comp:  2             [SII]6716      3.819      0.35     -63    39
# Comp:  2             [SII]6731      2.709      0.35     -63    39
# Comp:  2              HeII4687     0.4071      0.35     -63    39
# Comp:  2               HeI5876    0.01188      0.35     -63    39
# Comp:  2          [OIII]5007_d      4.520      0.44     -63    39
# Comp:  2            [OI]6300_d      1.224      0.44     -63    39
# Comp:  2           [NII]6583_d      2.658      0.44     -63    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -53        53
#  comp.  2:       -65        45
# chi2/DOF: 0.9654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.255      0.37     -53    53
# Comp:  1                Halpha      16.08      0.37     -53    53
# Comp:  2             [SII]6716      4.072      0.36     -65    45
# Comp:  2             [SII]6731      2.967      0.36     -65    45
# Comp:  2              HeII4687      0.000      0.36     -65    45
# Comp:  2               HeI5876     0.1917      0.36     -65    45
# Comp:  2          [OIII]5007_d      4.323      0.45     -65    45
# Comp:  2            [OI]6300_d      1.672      0.45     -65    45
# Comp:  2           [NII]6583_d      2.900      0.45     -65    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -53        51
#  comp.  2:       -59        50
# chi2/DOF: 0.9651; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.704      0.36     -53    51
# Comp:  1                Halpha      15.58      0.36     -53    51
# Comp:  2             [SII]6716      4.015      0.36     -59    50
# Comp:  2             [SII]6731      3.232      0.36     -59    50
# Comp:  2              HeII4687    0.05307      0.36     -59    50
# Comp:  2               HeI5876     0.2621      0.36     -59    50
# Comp:  2          [OIII]5007_d      4.734      0.46     -59    50
# Comp:  2            [OI]6300_d      1.669      0.46     -59    50
# Comp:  2           [NII]6583_d      2.805      0.46     -59    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        17
#  comp.  1:       -50        56
#  comp.  2:       -69        44
# chi2/DOF: 0.9630; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.394      0.37     -50    56
# Comp:  1                Halpha      16.19      0.37     -50    56
# Comp:  2             [SII]6716      4.007      0.36     -69    44
# Comp:  2             [SII]6731      2.964      0.36     -69    44
# Comp:  2              HeII4687    0.05014      0.36     -69    44
# Comp:  2               HeI5876   0.008410      0.36     -69    44
# Comp:  2          [OIII]5007_d      3.808      0.45     -69    44
# Comp:  2            [OI]6300_d      1.458      0.45     -69    44
# Comp:  2           [NII]6583_d      3.003      0.45     -69    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        43
#  comp.  1:       -54        55
#  comp.  2:       -64        43
# chi2/DOF: 0.9662; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.045      0.37     -54    55
# Comp:  1                Halpha      16.19      0.37     -54    55
# Comp:  2             [SII]6716      3.944      0.35     -64    43
# Comp:  2             [SII]6731      2.989      0.35     -64    43
# Comp:  2              HeII4687      0.000      0.35     -64    43
# Comp:  2               HeI5876      0.000      0.35     -64    43
# Comp:  2          [OIII]5007_d      4.550      0.45     -64    43
# Comp:  2            [OI]6300_d      1.272      0.45     -64    43
# Comp:  2           [NII]6583_d      3.072      0.45     -64    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        41
#  comp.  1:       -53        57
#  comp.  2:       -67        57
# chi2/DOF: 0.9587; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.782      0.37     -53    57
# Comp:  1                Halpha      16.02      0.37     -53    57
# Comp:  2             [SII]6716      4.122      0.37     -67    57
# Comp:  2             [SII]6731      3.287      0.37     -67    57
# Comp:  2              HeII4687     0.4542      0.37     -67    57
# Comp:  2               HeI5876    0.05398      0.37     -67    57
# Comp:  2          [OIII]5007_d      4.901      0.47     -67    57
# Comp:  2            [OI]6300_d      1.714      0.47     -67    57
# Comp:  2           [NII]6583_d      3.418      0.47     -67    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -54        53
#  comp.  2:       -70        46
# chi2/DOF: 0.9588; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.038      0.37     -54    53
# Comp:  1                Halpha      15.89      0.37     -54    53
# Comp:  2             [SII]6716      3.809      0.36     -70    46
# Comp:  2             [SII]6731      2.968      0.36     -70    46
# Comp:  2              HeII4687      0.000      0.36     -70    46
# Comp:  2               HeI5876     0.3864      0.36     -70    46
# Comp:  2          [OIII]5007_d      4.762      0.45     -70    46
# Comp:  2            [OI]6300_d      1.417      0.45     -70    46
# Comp:  2           [NII]6583_d      2.836      0.45     -70    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        47
#  comp.  1:       -53        54
#  comp.  2:       -65        44
# chi2/DOF: 0.9651; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.942      0.37     -53    54
# Comp:  1                Halpha      15.60      0.37     -53    54
# Comp:  2             [SII]6716      3.835      0.35     -65    44
# Comp:  2             [SII]6731      2.776      0.35     -65    44
# Comp:  2              HeII4687     0.1053      0.35     -65    44
# Comp:  2               HeI5876     0.1690      0.35     -65    44
# Comp:  2          [OIII]5007_d      4.286      0.45     -65    44
# Comp:  2            [OI]6300_d      1.251      0.45     -65    44
# Comp:  2           [NII]6583_d      2.554      0.45     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -54        55
#  comp.  2:       -58        44
# chi2/DOF: 0.9658; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.652      0.37     -54    55
# Comp:  1                Halpha      15.73      0.37     -54    55
# Comp:  2             [SII]6716      3.755      0.35     -58    44
# Comp:  2             [SII]6731      3.186      0.35     -58    44
# Comp:  2              HeII4687    0.06092      0.35     -58    44
# Comp:  2               HeI5876      0.000      0.35     -58    44
# Comp:  2          [OIII]5007_d      4.232      0.45     -58    44
# Comp:  2            [OI]6300_d      1.544      0.45     -58    44
# Comp:  2           [NII]6583_d      3.070      0.45     -58    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        30
#  comp.  1:       -57        53
#  comp.  2:       -59        50
# chi2/DOF: 0.9648; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.456      0.37     -57    53
# Comp:  1                Halpha      15.96      0.37     -57    53
# Comp:  2             [SII]6716      4.074      0.36     -59    50
# Comp:  2             [SII]6731      3.253      0.36     -59    50
# Comp:  2              HeII4687      0.000      0.36     -59    50
# Comp:  2               HeI5876     0.1291      0.36     -59    50
# Comp:  2          [OIII]5007_d      4.396      0.46     -59    50
# Comp:  2            [OI]6300_d      1.832      0.46     -59    50
# Comp:  2           [NII]6583_d      3.451      0.46     -59    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35       153
#  comp.  1:       -50        56
#  comp.  2:       -69        48
# chi2/DOF: 0.9630; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.391      0.37     -50    56
# Comp:  1                Halpha      15.95      0.37     -50    56
# Comp:  2             [SII]6716      3.862      0.36     -69    48
# Comp:  2             [SII]6731      3.069      0.36     -69    48
# Comp:  2              HeII4687      0.000      0.36     -69    48
# Comp:  2               HeI5876      0.000      0.36     -69    48
# Comp:  2          [OIII]5007_d      4.970      0.45     -69    48
# Comp:  2            [OI]6300_d      1.559      0.45     -69    48
# Comp:  2           [NII]6583_d      2.800      0.45     -69    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -52        56
#  comp.  2:       -63        52
# chi2/DOF: 0.9655; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.681      0.37     -52    56
# Comp:  1                Halpha      15.71      0.37     -52    56
# Comp:  2             [SII]6716      4.139      0.36     -63    52
# Comp:  2             [SII]6731      3.170      0.36     -63    52
# Comp:  2              HeII4687      0.000      0.36     -63    52
# Comp:  2               HeI5876     0.1536      0.36     -63    52
# Comp:  2          [OIII]5007_d      5.055      0.46     -63    52
# Comp:  2            [OI]6300_d      1.285      0.46     -63    52
# Comp:  2           [NII]6583_d      3.435      0.46     -63    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        26
#  comp.  1:       -54        55
#  comp.  2:       -64        45
# chi2/DOF: 0.9661; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.896      0.37     -54    55
# Comp:  1                Halpha      16.26      0.37     -54    55
# Comp:  2             [SII]6716      3.931      0.36     -64    45
# Comp:  2             [SII]6731      2.914      0.36     -64    45
# Comp:  2              HeII4687    0.08790      0.36     -64    45
# Comp:  2               HeI5876      0.000      0.36     -64    45
# Comp:  2          [OIII]5007_d      4.294      0.45     -64    45
# Comp:  2            [OI]6300_d      1.509      0.45     -64    45
# Comp:  2           [NII]6583_d      3.110      0.45     -64    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -51        57
#  comp.  2:       -71        45
# chi2/DOF: 0.9658; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.175      0.37     -51    57
# Comp:  1                Halpha      16.25      0.37     -51    57
# Comp:  2             [SII]6716      3.916      0.36     -71    45
# Comp:  2             [SII]6731      3.297      0.36     -71    45
# Comp:  2              HeII4687     0.3816      0.36     -71    45
# Comp:  2               HeI5876      0.000      0.36     -71    45
# Comp:  2          [OIII]5007_d      4.525      0.45     -71    45
# Comp:  2            [OI]6300_d      1.122      0.45     -71    45
# Comp:  2           [NII]6583_d      2.865      0.45     -71    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -52        58
#  comp.  2:       -66        51
# chi2/DOF: 0.9644; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.435      0.37     -52    58
# Comp:  1                Halpha      16.11      0.37     -52    58
# Comp:  2             [SII]6716      4.080      0.36     -66    51
# Comp:  2             [SII]6731      3.402      0.36     -66    51
# Comp:  2              HeII4687     0.1178      0.36     -66    51
# Comp:  2               HeI5876      0.000      0.36     -66    51
# Comp:  2          [OIII]5007_d      4.855      0.46     -66    51
# Comp:  2            [OI]6300_d      1.282      0.46     -66    51
# Comp:  2           [NII]6583_d      2.982      0.46     -66    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -55        52
#  comp.  2:       -65        44
# chi2/DOF: 0.9629; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.342      0.36     -55    52
# Comp:  1                Halpha      15.71      0.36     -55    52
# Comp:  2             [SII]6716      3.964      0.35     -65    44
# Comp:  2             [SII]6731      3.251      0.35     -65    44
# Comp:  2              HeII4687     0.1420      0.35     -65    44
# Comp:  2               HeI5876     0.1811      0.35     -65    44
# Comp:  2          [OIII]5007_d      4.172      0.45     -65    44
# Comp:  2            [OI]6300_d      1.625      0.45     -65    44
# Comp:  2           [NII]6583_d      2.865      0.45     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        52
#  comp.  1:       -53        55
#  comp.  2:       -65        45
# chi2/DOF: 0.9651; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.840      0.37     -53    55
# Comp:  1                Halpha      15.67      0.37     -53    55
# Comp:  2             [SII]6716      4.031      0.36     -65    45
# Comp:  2             [SII]6731      3.228      0.36     -65    45
# Comp:  2              HeII4687    0.03862      0.36     -65    45
# Comp:  2               HeI5876     0.2356      0.36     -65    45
# Comp:  2          [OIII]5007_d      4.539      0.45     -65    45
# Comp:  2            [OI]6300_d      1.385      0.45     -65    45
# Comp:  2           [NII]6583_d      3.053      0.45     -65    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -56        52
#  comp.  2:       -67        46
# chi2/DOF: 0.9592; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.878      0.36     -56    52
# Comp:  1                Halpha      16.01      0.36     -56    52
# Comp:  2             [SII]6716      3.844      0.36     -67    46
# Comp:  2             [SII]6731      2.710      0.36     -67    46
# Comp:  2              HeII4687     0.3372      0.36     -67    46
# Comp:  2               HeI5876      0.000      0.36     -67    46
# Comp:  2          [OIII]5007_d      5.077      0.45     -67    46
# Comp:  2            [OI]6300_d      1.533      0.45     -67    46
# Comp:  2           [NII]6583_d      3.037      0.45     -67    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -54        55
#  comp.  2:       -66        53
# chi2/DOF: 0.9675; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.272      0.37     -54    55
# Comp:  1                Halpha      15.91      0.37     -54    55
# Comp:  2             [SII]6716      4.190      0.37     -66    53
# Comp:  2             [SII]6731      3.114      0.37     -66    53
# Comp:  2              HeII4687      0.000      0.37     -66    53
# Comp:  2               HeI5876    0.05376      0.37     -66    53
# Comp:  2          [OIII]5007_d      4.879      0.46     -66    53
# Comp:  2            [OI]6300_d      1.688      0.46     -66    53
# Comp:  2           [NII]6583_d      3.122      0.46     -66    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        24
#  comp.  1:       -50        53
#  comp.  2:       -65        39
# chi2/DOF: 0.9653; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.702      0.37     -50    53
# Comp:  1                Halpha      15.81      0.37     -50    53
# Comp:  2             [SII]6716      3.915      0.35     -65    39
# Comp:  2             [SII]6731      2.969      0.35     -65    39
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.496      0.37     -54    59
# Comp:  1                Halpha      16.30      0.37     -54    59
# Comp:  2             [SII]6716      4.061      0.36     -65    47
# Comp:  2             [SII]6731      2.999      0.36     -65    47
# Comp:  2              HeII4687      0.000      0.36     -65    47
# Comp:  2               HeI5876     0.1219      0.36     -65    47
# Comp:  2          [OIII]5007_d      4.165      0.45     -65    47
# Comp:  2            [OI]6300_d      1.492      0.45     -65    47
# Comp:  2           [NII]6583_d      3.320      0.45     -65    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -53        56
#  comp.  2:       -67        44
# chi2/DOF: 0.9644; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.955      0.37     -53    56
# Comp:  1                Halpha      15.84      0.37     -53    56
# Comp:  2             [SII]6716      3.866      0.35     -67    44
# Comp:  2             [SII]6731      2.794      0.35     -67    44
# Comp:  2              HeII4687     0.3285      0.35     -67    44
# Comp:  2               HeI5876     0.3941      0.35     -67    44
# Comp:  2          [OIII]5007_d      4.957      0.45     -67    44
# Comp:  2            [OI]6300_d      1.630      0.45     -67    44
# Comp:  2           [NII]6583_d      2.981      0.45     -67    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        32
#  comp.  1:       -50        55
#  comp.  2:       -71        42
# chi2/DOF: 0.9632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.115      0.37     -50    55
# Comp:  1                Halpha      16.42      0.37     -50    55
# Comp:  2             [SII]6716      3.889      0.35     -71    42
# Comp:  2             [SII]6731      2.966      0.35     -71    42
# Comp:  2              HeII4687    0.02421      0.35     -71    42
# Comp:  2               HeI5876    0.03641      0.35     -71    42
# Comp:  2          [OIII]5007_d      4.576      0.44     -71    42
# Comp:  2            [OI]6300_d      1.682      0.44     -71    42
# Comp:  2           [NII]6583_d      2.617      0.44     -71    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -58        56
#  comp.  2:       -62        55
# chi2/DOF: 0.9655; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.008      0.37     -58    56
# Comp:  1                Halpha      15.92      0.37     -58    56
# Comp:  2             [SII]6716      4.068      0.37     -62    55
# Comp:  2             [SII]6731      3.330      0.37     -62    55
# Comp:  2              HeII4687     0.3621      0.37     -62    55
# Comp:  2               HeI5876     0.1918      0.37     -62    55
# Comp:  2          [OIII]5007_d      4.436      0.47     -62    55
# Comp:  2            [OI]6300_d      1.361      0.47     -62    55
# Comp:  2           [NII]6583_d      3.437      0.47     -62    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        26
#  comp.  1:       -53        54
#  comp.  2:       -64        44
# chi2/DOF: 0.9583; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.043      0.37     -53    54
# Comp:  1                Halpha      16.45      0.37     -53    54
# Comp:  2             [SII]6716      3.817      0.36     -64    44
# Comp:  2             [SII]6731      2.751      0.36     -64    44
# Comp:  2              HeII4687    0.09089      0.36     -64    44
# Comp:  2               HeI5876     0.2430      0.36     -64    44
# Comp:  2          [OIII]5007_d      4.315      0.45     -64    44
# Comp:  2            [OI]6300_d      1.285      0.45     -64    44
# Comp:  2           [NII]6583_d      2.692      0.45     -64    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -54        55
#  comp.  2:       -69        40
# chi2/DOF: 0.9593; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.916      0.37     -54    55
# Comp:  1                Halpha      16.38      0.37     -54    55
# Comp:  2             [SII]6716      3.944      0.35     -69    40
# Comp:  2             [SII]6731      3.012      0.35     -69    40
# Comp:  2              HeII4687      0.000      0.35     -69    40
# Comp:  2               HeI5876     0.3337      0.35     -69    40
# Comp:  2          [OIII]5007_d      4.640      0.44     -69    40
# Comp:  2            [OI]6300_d      1.143      0.44     -69    40
# Comp:  2           [NII]6583_d      2.827      0.44     -69    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -53        56
#  comp.  2:       -67        52
# chi2/DOF: 0.9656; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.977      0.37     -53    56
# Comp:  1                Halpha      16.08      0.37     -53    56
# Comp:  2             [SII]6716      3.963      0.36     -67    52
# Comp:  2             [SII]6731      3.299      0.36     -67    52
# Comp:  2              HeII4687    0.05562      0.36     -67    52
# Comp:  2               HeI5876     0.1583      0.36     -67    52
# Comp:  2          [OIII]5007_d      4.947      0.46     -67    52
# Comp:  2            [OI]6300_d      1.074      0.46     -67    52
# Comp:  2           [NII]6583_d      3.412      0.46     -67    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -53        56
#  comp.  2:       -66        50
# chi2/DOF: 0.9654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.772      0.37     -53    56
# Comp:  1                Halpha      16.43      0.37     -53    56
# Comp:  2             [SII]6716      4.091      0.36     -66    50
# Comp:  2             [SII]6731      2.766      0.36     -66    50
# Comp:  2              HeII4687      0.000      0.36     -66    50
# Comp:  2               HeI5876      0.000      0.36     -66    50
# Comp:  2          [OIII]5007_d      5.013      0.46     -66    50
# Comp:  2            [OI]6300_d      1.313      0.46     -66    50
# Comp:  2           [NII]6583_d      3.170      0.46     -66    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        19
#  comp.  1:       -55        53
#  comp.  2:       -58        46
# chi2/DOF: 0.9674; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.043      0.37     -55    53
# Comp:  1                Halpha      15.96      0.37     -55    53
# Comp:  2             [SII]6716      4.020      0.36     -58    46
# Comp:  2             [SII]6731      2.950      0.36     -58    46
# Comp:  2              HeII4687     0.2381      0.36     -58    46
# Comp:  2               HeI5876    0.04734      0.36     -58    46
# Comp:  2          [OIII]5007_d      4.540      0.45     -58    46
# Comp:  2            [OI]6300_d      1.764      0.45     -58    46
# Comp:  2           [NII]6583_d      3.164      0.45     -58    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        40
#  comp.  1:       -53        55
#  comp.  2:       -65        44
# chi2/DOF: 0.9617; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.053      0.37     -53    55
# Comp:  1                Halpha      16.34      0.37     -53    55
# Comp:  2             [SII]6716      3.925      0.36     -65    44
# Comp:  2             [SII]6731      3.119      0.36     -65    44
# Comp:  2              HeII4687    0.01578      0.36     -65    44
# Comp:  2               HeI5876     0.1060      0.36     -65    44
# Comp:  2          [OIII]5007_d      4.026      0.45     -65    44
# Comp:  2            [OI]6300_d      1.725      0.45     -65    44
# Comp:  2           [NII]6583_d      2.673      0.45     -65    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         6
#  comp.  1:       -53        58
#  comp.  2:       -66        37
# chi2/DOF: 0.9638; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.470      0.37     -53    58
# Comp:  1                Halpha      16.05      0.37     -53    58
# Comp:  2             [SII]6716      3.849      0.35     -66    37
# Comp:  2             [SII]6731      2.859      0.35     -66    37
# Comp:  2              HeII4687     0.1883      0.35     -66    37
# Comp:  2               HeI5876      0.000      0.35     -66    37
# Comp:  2          [OIII]5007_d      4.228      0.44     -66    37
# Comp:  2            [OI]6300_d      1.503      0.44     -66    37
# Comp:  2           [NII]6583_d      2.792      0.44     -66    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        41
#  comp.  1:       -52        56
#  comp.  2:       -62        44
# chi2/DOF: 0.9651; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.168      0.37     -52    56
# Comp:  1                Halpha      16.29      0.37     -52    56
# Comp:  2             [SII]6716      3.915      0.35     -62    44
# Comp:  2             [SII]6731      3.136      0.35     -62    44
# Comp:  2              HeII4687     0.3075      0.35     -62    44
# Comp:  2               HeI5876      0.000      0.35     -62    44
# Comp:  2          [OIII]5007_d      4.489      0.45     -62    44
# Comp:  2            [OI]6300_d      1.409      0.45     -62    44
# Comp:  2           [NII]6583_d      2.659      0.45     -62    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -54        54
#  comp.  2:       -71        36
# chi2/DOF: 0.9621; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.078      0.37     -54    54
# Comp:  1                Halpha      16.27      0.37     -54    54
# Comp:  2             [SII]6716      3.864      0.34     -71    36
# Comp:  2             [SII]6731      2.928      0.34     -71    36
# Comp:  2              HeII4687      0.000      0.34     -71    36
# Comp:  2               HeI5876    0.02565      0.34     -71    36
# Comp:  2          [OIII]5007_d      4.762      0.44     -71    36
# Comp:  2            [OI]6300_d      1.439      0.44     -71    36
# Comp:  2           [NII]6583_d      2.716      0.44     -71    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -54        55
#  comp.  2:       -70        42
# chi2/DOF: 0.9641; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.224      0.37     -54    55
# Comp:  1                Halpha      16.48      0.37     -54    55
# Comp:  2             [SII]6716      4.009      0.35     -70    42
# Comp:  2             [SII]6731      2.945      0.35     -70    42
# Comp:  2              HeII4687      0.000      0.35     -70    42
# Comp:  2               HeI5876     0.1674      0.35     -70    42
# Comp:  2          [OIII]5007_d      4.526      0.45     -70    42
# Comp:  2            [OI]6300_d      1.217      0.45     -70    42
# Comp:  2           [NII]6583_d      2.727      0.45     -70    42
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.49001602, 0.38540853, 0.13198807, 0.24311772, 0.11203454,
#        0.13207452, 0.37583215, 0.25796804, 0.27903005])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_2_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
