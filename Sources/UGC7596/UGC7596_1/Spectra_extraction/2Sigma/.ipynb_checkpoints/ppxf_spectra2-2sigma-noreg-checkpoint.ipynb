# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = red[1][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4444.779367   4446.25657507 4447.73378315 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.05915527 0.0553138  0.04416383 ... 0.02522834 0.03135124 0.03046263] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        22
# chi2/DOF: 0.02425; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
# chi2/DOF: 0.01669; DOF: 1913; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-69.29606348,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        12
#  comp.  1:       -74        56
#  comp.  2:       -92        91
# chi2/DOF: 1.007; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8540      0.35     -74    56
# Comp:  1                Halpha      3.527      0.35     -74    56
# Comp:  2             [SII]6716      1.941      0.40     -92    91
# Comp:  2             [SII]6731     0.9551      0.40     -92    91
# Comp:  2              HeII4687    0.09372      0.40     -92    91
# Comp:  2               HeI5876    0.07493      0.40     -92    91
# Comp:  2          [OIII]5007_d      1.343      0.51     -92    91
# Comp:  2            [OI]6300_d     0.8902      0.51     -92    91
# Comp:  2           [NII]6583_d      1.434      0.51     -92    91
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  1.788; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  7.291; gas flux:      5 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  3.249; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.572; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.1568; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.1252; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  1.672; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   1.09; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.796; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -66        62
#  comp.  2:       -88       108
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.752      0.36     -66    62
# Comp:  1                Halpha      4.151      0.36     -66    62
# Comp:  2             [SII]6716      2.201      0.42     -88   108
# Comp:  2             [SII]6731     0.9505      0.42     -88   108
# Comp:  2              HeII4687      0.000      0.42     -88   108
# Comp:  2               HeI5876      0.000      0.42     -88   108
# Comp:  2          [OIII]5007_d      1.113      0.54     -88   108
# Comp:  2            [OI]6300_d      1.144      0.54     -88   108
# Comp:  2           [NII]6583_d      1.343      0.54     -88   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -74        65
#  comp.  2:      -119        99
# chi2/DOF: 0.9960; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.229      0.36     -74    65
# Comp:  1                Halpha      3.980      0.36     -74    65
# Comp:  2             [SII]6716      1.976      0.41    -119    99
# Comp:  2             [SII]6731     0.9434      0.41    -119    99
# Comp:  2              HeII4687     0.3259      0.41    -119    99
# Comp:  2               HeI5876     0.4876      0.41    -119    99
# Comp:  2          [OIII]5007_d      1.419      0.52    -119    99
# Comp:  2            [OI]6300_d     0.6182      0.52    -119    99
# Comp:  2           [NII]6583_d      1.707      0.52    -119    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:       -81        71
#  comp.  2:       -93        91
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.202      0.37     -81    71
# Comp:  1                Halpha      3.950      0.37     -81    71
# Comp:  2             [SII]6716      1.826      0.40     -93    91
# Comp:  2             [SII]6731      1.006      0.40     -93    91
# Comp:  2              HeII4687    0.01054      0.40     -93    91
# Comp:  2               HeI5876      0.000      0.40     -93    91
# Comp:  2          [OIII]5007_d      1.974      0.51     -93    91
# Comp:  2            [OI]6300_d     0.9461      0.51     -93    91
# Comp:  2           [NII]6583_d      1.262      0.51     -93    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:       -79        45
#  comp.  2:       -92        98
# chi2/DOF: 0.9947; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.047      0.34     -79    45
# Comp:  1                Halpha      3.482      0.34     -79    45
# Comp:  2             [SII]6716      2.298      0.41     -92    98
# Comp:  2             [SII]6731      1.075      0.41     -92    98
# Comp:  2              HeII4687     0.1320      0.41     -92    98
# Comp:  2               HeI5876    0.04040      0.41     -92    98
# Comp:  2          [OIII]5007_d      1.194      0.52     -92    98
# Comp:  2            [OI]6300_d     0.5392      0.52     -92    98
# Comp:  2           [NII]6583_d      1.520      0.52     -92    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        43
#  comp.  1:       -74        61
#  comp.  2:       -83        85
# chi2/DOF: 0.9952; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.068      0.36     -74    61
# Comp:  1                Halpha      3.673      0.36     -74    61
# Comp:  2             [SII]6716      2.069      0.39     -83    85
# Comp:  2             [SII]6731      1.076      0.39     -83    85
# Comp:  2              HeII4687     0.2276      0.39     -83    85
# Comp:  2               HeI5876    0.07789      0.39     -83    85
# Comp:  2          [OIII]5007_d     0.6231      0.49     -83    85
# Comp:  2            [OI]6300_d     0.5685      0.49     -83    85
# Comp:  2           [NII]6583_d      1.083      0.49     -83    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        15
#  comp.  1:       -76        60
#  comp.  2:      -101        91
# chi2/DOF: 0.9981; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.048      0.36     -76    60
# Comp:  1                Halpha      4.302      0.36     -76    60
# Comp:  2             [SII]6716      1.966      0.40    -101    91
# Comp:  2             [SII]6731     0.9714      0.40    -101    91
# Comp:  2              HeII4687      0.000      0.40    -101    91
# Comp:  2               HeI5876      1.015      0.40    -101    91
# Comp:  2          [OIII]5007_d      1.219      0.51    -101    91
# Comp:  2            [OI]6300_d     0.8653      0.51    -101    91
# Comp:  2           [NII]6583_d      1.283      0.51    -101    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -72        53
#  comp.  2:       -86        95
# chi2/DOF: 0.9944; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.188      0.35     -72    53
# Comp:  1                Halpha      3.599      0.35     -72    53
# Comp:  2             [SII]6716      2.012      0.41     -86    95
# Comp:  2             [SII]6731      1.103      0.41     -86    95
# Comp:  2              HeII4687      0.000      0.41     -86    95
# Comp:  2               HeI5876      0.000      0.41     -86    95
# Comp:  2          [OIII]5007_d     0.9572      0.51     -86    95
# Comp:  2            [OI]6300_d     0.9947      0.51     -86    95
# Comp:  2           [NII]6583_d      1.755      0.51     -86    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -77        54
#  comp.  2:       -92        86
# chi2/DOF: 0.9997; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8993      0.35     -77    54
# Comp:  1                Halpha      3.651      0.35     -77    54
# Comp:  2             [SII]6716      1.884      0.39     -92    86
# Comp:  2             [SII]6731     0.8751      0.39     -92    86
# Comp:  2              HeII4687     0.5053      0.39     -92    86
# Comp:  2               HeI5876      0.000      0.39     -92    86
# Comp:  2          [OIII]5007_d     0.9399      0.50     -92    86
# Comp:  2            [OI]6300_d     0.4758      0.50     -92    86
# Comp:  2           [NII]6583_d      1.426      0.50     -92    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -69        46
#  comp.  2:       -83        89
# chi2/DOF: 0.9995; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.321      0.34     -69    46
# Comp:  1                Halpha      3.661      0.34     -69    46
# Comp:  2             [SII]6716      1.919      0.40     -83    89
# Comp:  2             [SII]6731      1.095      0.40     -83    89
# Comp:  2              HeII4687     0.1371      0.40     -83    89
# Comp:  2               HeI5876      0.000      0.40     -83    89
# Comp:  2          [OIII]5007_d      1.515      0.50     -83    89
# Comp:  2            [OI]6300_d     0.4768      0.50     -83    89
# Comp:  2           [NII]6583_d      1.079      0.50     -83    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        33
#  comp.  1:       -81        58
#  comp.  2:      -103        68
# chi2/DOF: 0.9951; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8043      0.35     -81    58
# Comp:  1                Halpha      3.397      0.35     -81    58
# Comp:  2             [SII]6716      1.659      0.37    -103    68
# Comp:  2             [SII]6731     0.8777      0.37    -103    68
# Comp:  2              HeII4687      0.000      0.37    -103    68
# Comp:  2               HeI5876     0.6527      0.37    -103    68
# Comp:  2          [OIII]5007_d     0.3544      0.47    -103    68
# Comp:  2            [OI]6300_d     0.8486      0.47    -103    68
# Comp:  2           [NII]6583_d      1.060      0.47    -103    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         3
#  comp.  1:       -69        61
#  comp.  2:       -81        91
# chi2/DOF: 0.9989; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7745      0.36     -69    61
# Comp:  1                Halpha      3.672      0.36     -69    61
# Comp:  2             [SII]6716      2.043      0.40     -81    91
# Comp:  2             [SII]6731      1.042      0.40     -81    91
# Comp:  2              HeII4687      0.000      0.40     -81    91
# Comp:  2               HeI5876     0.4580      0.40     -81    91
# Comp:  2          [OIII]5007_d      1.692      0.50     -81    91
# Comp:  2            [OI]6300_d     0.6418      0.50     -81    91
# Comp:  2           [NII]6583_d      1.789      0.50     -81    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        45
#  comp.  1:       -70        57
#  comp.  2:       -96        84
# chi2/DOF: 1.002; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9596      0.35     -70    57
# Comp:  1                Halpha      3.673      0.35     -70    57
# Comp:  2             [SII]6716      1.974      0.39     -96    84
# Comp:  2             [SII]6731     0.9893      0.39     -96    84
# Comp:  2              HeII4687      0.000      0.39     -96    84
# Comp:  2               HeI5876      0.000      0.39     -96    84
# Comp:  2          [OIII]5007_d      1.153      0.49     -96    84
# Comp:  2            [OI]6300_d     0.8680      0.49     -96    84
# Comp:  2           [NII]6583_d      1.433      0.49     -96    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -85        61
#  comp.  2:      -106        84
# chi2/DOF: 0.9965; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.384      0.36     -85    61
# Comp:  1                Halpha      3.683      0.36     -85    61
# Comp:  2             [SII]6716      2.252      0.39    -106    84
# Comp:  2             [SII]6731     0.9505      0.39    -106    84
# Comp:  2              HeII4687      0.000      0.39    -106    84
# Comp:  2               HeI5876      0.000      0.39    -106    84
# Comp:  2          [OIII]5007_d      2.023      0.49    -106    84
# Comp:  2            [OI]6300_d     0.6857      0.49    -106    84
# Comp:  2           [NII]6583_d      1.356      0.49    -106    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        16
#  comp.  1:       -74        47
#  comp.  2:       -64        95
# chi2/DOF: 0.9993; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.083      0.34     -74    47
# Comp:  1                Halpha      3.712      0.34     -74    47
# Comp:  2             [SII]6716      1.838      0.41     -64    95
# Comp:  2             [SII]6731      1.065      0.41     -64    95
# Comp:  2              HeII4687      0.000      0.41     -64    95
# Comp:  2               HeI5876      0.000      0.41     -64    95
# Comp:  2          [OIII]5007_d      1.052      0.51     -64    95
# Comp:  2            [OI]6300_d     0.9138      0.51     -64    95
# Comp:  2           [NII]6583_d      1.389      0.51     -64    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -66        69
#  comp.  2:       -90        61
# chi2/DOF: 0.9975; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.303      0.37     -66    69
# Comp:  1                Halpha      3.586      0.37     -66    69
# Comp:  2             [SII]6716      1.753      0.36     -90    61
# Comp:  2             [SII]6731     0.7199      0.36     -90    61
# Comp:  2              HeII4687    0.02015      0.36     -90    61
# Comp:  2               HeI5876      0.000      0.36     -90    61
# Comp:  2          [OIII]5007_d     0.5837      0.45     -90    61
# Comp:  2            [OI]6300_d     0.7004      0.45     -90    61
# Comp:  2           [NII]6583_d      1.384      0.45     -90    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         4
#  comp.  1:       -69        61
#  comp.  2:      -104        91
# chi2/DOF: 1.002; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9270      0.36     -69    61
# Comp:  1                Halpha      3.393      0.36     -69    61
# Comp:  2             [SII]6716      1.983      0.40    -104    91
# Comp:  2             [SII]6731     0.9834      0.40    -104    91
# Comp:  2              HeII4687      0.000      0.40    -104    91
# Comp:  2               HeI5876      0.000      0.40    -104    91
# Comp:  2          [OIII]5007_d      1.793      0.50    -104    91
# Comp:  2            [OI]6300_d      1.111      0.50    -104    91
# Comp:  2           [NII]6583_d      1.103      0.50    -104    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        51
#  comp.  1:       -62        65
#  comp.  2:       -80       116
# chi2/DOF: 0.9946; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.210      0.36     -62    65
# Comp:  1                Halpha      3.917      0.36     -62    65
# Comp:  2             [SII]6716      2.122      0.44     -80   116
# Comp:  2             [SII]6731      1.056      0.44     -80   116
# Comp:  2              HeII4687    0.03130      0.44     -80   116
# Comp:  2               HeI5876      0.000      0.44     -80   116
# Comp:  2          [OIII]5007_d     0.9822      0.55     -80   116
# Comp:  2            [OI]6300_d      1.064      0.55     -80   116
# Comp:  2           [NII]6583_d      1.967      0.55     -80   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        96
#  comp.  1:       -72        72
#  comp.  2:      -108       108
# chi2/DOF: 0.9948; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7037      0.37     -72    72
# Comp:  1                Halpha      3.572      0.37     -72    72
# Comp:  2             [SII]6716      2.268      0.42    -108   108
# Comp:  2             [SII]6731      1.180      0.42    -108   108
# Comp:  2              HeII4687      0.000      0.42    -108   108
# Comp:  2               HeI5876      0.000      0.42    -108   108
# Comp:  2          [OIII]5007_d     0.7171      0.54    -108   108
# Comp:  2            [OI]6300_d     0.3576      0.54    -108   108
# Comp:  2           [NII]6583_d      1.484      0.54    -108   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         7
#  comp.  1:       -62        64
#  comp.  2:      -104        95
# chi2/DOF: 0.9998; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.479      0.36     -62    64
# Comp:  1                Halpha      3.698      0.36     -62    64
# Comp:  2             [SII]6716      1.853      0.41    -104    95
# Comp:  2             [SII]6731     0.9911      0.41    -104    95
# Comp:  2              HeII4687     0.3512      0.41    -104    95
# Comp:  2               HeI5876     0.2102      0.41    -104    95
# Comp:  2          [OIII]5007_d     0.9396      0.51    -104    95
# Comp:  2            [OI]6300_d      1.176      0.51    -104    95
# Comp:  2           [NII]6583_d      1.070      0.51    -104    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108        31
#  comp.  1:       -91        69
#  comp.  2:       -73        96
# chi2/DOF: 0.9933; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.617      0.37     -91    69
# Comp:  1                Halpha      3.768      0.37     -91    69
# Comp:  2             [SII]6716      1.847      0.41     -73    96
# Comp:  2             [SII]6731     0.8439      0.41     -73    96
# Comp:  2              HeII4687     0.3521      0.41     -73    96
# Comp:  2               HeI5876      0.000      0.41     -73    96
# Comp:  2          [OIII]5007_d      1.259      0.51     -73    96
# Comp:  2            [OI]6300_d     0.9111      0.51     -73    96
# Comp:  2           [NII]6583_d      1.826      0.51     -73    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        30
#  comp.  1:       -76        54
#  comp.  2:       -93        81
# chi2/DOF: 1.004; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.137      0.35     -76    54
# Comp:  1                Halpha      3.874      0.35     -76    54
# Comp:  2             [SII]6716      2.068      0.39     -93    81
# Comp:  2             [SII]6731     0.7949      0.39     -93    81
# Comp:  2              HeII4687      0.000      0.39     -93    81
# Comp:  2               HeI5876     0.1144      0.39     -93    81
# Comp:  2          [OIII]5007_d      1.159      0.49     -93    81
# Comp:  2            [OI]6300_d     0.7391      0.49     -93    81
# Comp:  2           [NII]6583_d      1.720      0.49     -93    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -73        59
#  comp.  2:       -94        89
# chi2/DOF: 0.9975; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8434      0.36     -73    59
# Comp:  1                Halpha      3.796      0.36     -73    59
# Comp:  2             [SII]6716      2.008      0.40     -94    89
# Comp:  2             [SII]6731     0.9201      0.40     -94    89
# Comp:  2              HeII4687     0.3221      0.40     -94    89
# Comp:  2               HeI5876     0.4893      0.40     -94    89
# Comp:  2          [OIII]5007_d      1.766      0.50     -94    89
# Comp:  2            [OI]6300_d     0.6787      0.50     -94    89
# Comp:  2           [NII]6583_d      1.719      0.50     -94    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -73        59
#  comp.  2:       -92        91
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.481      0.36     -73    59
# Comp:  1                Halpha      3.601      0.36     -73    59
# Comp:  2             [SII]6716      2.221      0.40     -92    91
# Comp:  2             [SII]6731     0.7842      0.40     -92    91
# Comp:  2              HeII4687     0.1157      0.40     -92    91
# Comp:  2               HeI5876     0.1384      0.40     -92    91
# Comp:  2          [OIII]5007_d      1.326      0.51     -92    91
# Comp:  2            [OI]6300_d     0.6017      0.51     -92    91
# Comp:  2           [NII]6583_d      1.536      0.51     -92    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -74        61
#  comp.  2:       -98       128
# chi2/DOF: 0.9914; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8414      0.36     -74    61
# Comp:  1                Halpha      4.015      0.36     -74    61
# Comp:  2             [SII]6716      2.282      0.45     -98   128
# Comp:  2             [SII]6731      1.376      0.45     -98   128
# Comp:  2              HeII4687     0.2542      0.45     -98   128
# Comp:  2               HeI5876      0.000      0.45     -98   128
# Comp:  2          [OIII]5007_d      1.282      0.57     -98   128
# Comp:  2            [OI]6300_d      1.472      0.57     -98   128
# Comp:  2           [NII]6583_d      1.622      0.57     -98   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       -72        51
#  comp.  2:      -105       110
# chi2/DOF: 0.9966; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4573      0.34     -72    51
# Comp:  1                Halpha      3.337      0.34     -72    51
# Comp:  2             [SII]6716      2.205      0.43    -105   110
# Comp:  2             [SII]6731      1.072      0.43    -105   110
# Comp:  2              HeII4687      0.000      0.43    -105   110
# Comp:  2               HeI5876     0.5044      0.43    -105   110
# Comp:  2          [OIII]5007_d      1.423      0.54    -105   110
# Comp:  2            [OI]6300_d     0.9510      0.54    -105   110
# Comp:  2           [NII]6583_d     0.9635      0.54    -105   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        10
#  comp.  1:       -71        79
#  comp.  2:       -91        82
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.863      0.38     -71    79
# Comp:  1                Halpha      4.248      0.38     -71    79
# Comp:  2             [SII]6716      1.741      0.39     -91    82
# Comp:  2             [SII]6731     0.8581      0.39     -91    82
# Comp:  2              HeII4687      0.000      0.39     -91    82
# Comp:  2               HeI5876     0.6315      0.39     -91    82
# Comp:  2          [OIII]5007_d      1.182      0.49     -91    82
# Comp:  2            [OI]6300_d     0.8054      0.49     -91    82
# Comp:  2           [NII]6583_d      1.184      0.49     -91    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -73        63
#  comp.  2:       -79        75
# chi2/DOF: 1.001; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.344      0.36     -73    63
# Comp:  1                Halpha      3.671      0.36     -73    63
# Comp:  2             [SII]6716      1.847      0.38     -79    75
# Comp:  2             [SII]6731     0.8969      0.38     -79    75
# Comp:  2              HeII4687     0.4196      0.38     -79    75
# Comp:  2               HeI5876     0.1200      0.38     -79    75
# Comp:  2          [OIII]5007_d      1.470      0.48     -79    75
# Comp:  2            [OI]6300_d     0.7805      0.48     -79    75
# Comp:  2           [NII]6583_d      1.743      0.48     -79    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        32
#  comp.  1:       -63        56
#  comp.  2:      -114        92
# chi2/DOF: 0.9964; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5916      0.35     -63    56
# Comp:  1                Halpha      3.295      0.35     -63    56
# Comp:  2             [SII]6716      2.038      0.40    -114    92
# Comp:  2             [SII]6731      1.024      0.40    -114    92
# Comp:  2              HeII4687     0.1484      0.40    -114    92
# Comp:  2               HeI5876      0.000      0.40    -114    92
# Comp:  2          [OIII]5007_d      1.754      0.51    -114    92
# Comp:  2            [OI]6300_d      1.061      0.51    -114    92
# Comp:  2           [NII]6583_d      1.260      0.51    -114    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -72        64
#  comp.  2:       -83       106
# chi2/DOF: 0.9982; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.781      0.36     -72    64
# Comp:  1                Halpha      4.095      0.36     -72    64
# Comp:  2             [SII]6716      2.205      0.42     -83   106
# Comp:  2             [SII]6731     0.9962      0.42     -83   106
# Comp:  2              HeII4687      0.000      0.42     -83   106
# Comp:  2               HeI5876     0.5738      0.42     -83   106
# Comp:  2          [OIII]5007_d      2.195      0.53     -83   106
# Comp:  2            [OI]6300_d      1.085      0.53     -83   106
# Comp:  2           [NII]6583_d      1.313      0.53     -83   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -75        48
#  comp.  2:       -85        83
# chi2/DOF: 0.9975; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7826      0.34     -75    48
# Comp:  1                Halpha      3.259      0.34     -75    48
# Comp:  2             [SII]6716      2.090      0.39     -85    83
# Comp:  2             [SII]6731     0.7235      0.39     -85    83
# Comp:  2              HeII4687     0.4672      0.39     -85    83
# Comp:  2               HeI5876      0.000      0.39     -85    83
# Comp:  2          [OIII]5007_d      1.029      0.49     -85    83
# Comp:  2            [OI]6300_d     0.3227      0.49     -85    83
# Comp:  2           [NII]6583_d      1.521      0.49     -85    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:       -83        58
#  comp.  2:       -82        79
# chi2/DOF: 0.9963; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.006      0.35     -83    58
# Comp:  1                Halpha      3.636      0.35     -83    58
# Comp:  2             [SII]6716      1.716      0.38     -82    79
# Comp:  2             [SII]6731     0.7303      0.38     -82    79
# Comp:  2              HeII4687      0.000      0.38     -82    79
# Comp:  2               HeI5876     0.2592      0.38     -82    79
# Comp:  2          [OIII]5007_d     0.4374      0.48     -82    79
# Comp:  2            [OI]6300_d      1.083      0.48     -82    79
# Comp:  2           [NII]6583_d      1.343      0.48     -82    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -68        59
#  comp.  2:       -87        93
# chi2/DOF: 0.9977; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.134      0.35     -68    59
# Comp:  1                Halpha      3.523      0.35     -68    59
# Comp:  2             [SII]6716      1.687      0.40     -87    93
# Comp:  2             [SII]6731      1.005      0.40     -87    93
# Comp:  2              HeII4687     0.2457      0.40     -87    93
# Comp:  2               HeI5876     0.9833      0.40     -87    93
# Comp:  2          [OIII]5007_d     0.7362      0.51     -87    93
# Comp:  2            [OI]6300_d      1.019      0.51     -87    93
# Comp:  2           [NII]6583_d      1.545      0.51     -87    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -69        59
#  comp.  2:      -101       109
# chi2/DOF: 0.9986; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.286      0.36     -69    59
# Comp:  1                Halpha      4.027      0.36     -69    59
# Comp:  2             [SII]6716      2.401      0.43    -101   109
# Comp:  2             [SII]6731      1.014      0.43    -101   109
# Comp:  2              HeII4687     0.2436      0.43    -101   109
# Comp:  2               HeI5876      0.000      0.43    -101   109
# Comp:  2          [OIII]5007_d      1.416      0.54    -101   109
# Comp:  2            [OI]6300_d      1.199      0.54    -101   109
# Comp:  2           [NII]6583_d      1.669      0.54    -101   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        80
#  comp.  1:       -79        68
#  comp.  2:       -98        85
# chi2/DOF: 0.9930; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.054      0.37     -79    68
# Comp:  1                Halpha      3.669      0.37     -79    68
# Comp:  2             [SII]6716      2.108      0.39     -98    85
# Comp:  2             [SII]6731     0.8824      0.39     -98    85
# Comp:  2              HeII4687     0.1883      0.39     -98    85
# Comp:  2               HeI5876     0.4788      0.39     -98    85
# Comp:  2          [OIII]5007_d      1.273      0.50     -98    85
# Comp:  2            [OI]6300_d     0.9020      0.50     -98    85
# Comp:  2           [NII]6583_d      1.755      0.50     -98    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -68        57
#  comp.  2:       -91       104
# chi2/DOF: 0.9990; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.190      0.35     -68    57
# Comp:  1                Halpha      3.789      0.35     -68    57
# Comp:  2             [SII]6716      2.023      0.42     -91   104
# Comp:  2             [SII]6731      1.208      0.42     -91   104
# Comp:  2              HeII4687     0.2025      0.42     -91   104
# Comp:  2               HeI5876    0.04362      0.42     -91   104
# Comp:  2          [OIII]5007_d      1.198      0.53     -91   104
# Comp:  2            [OI]6300_d     0.8947      0.53     -91   104
# Comp:  2           [NII]6583_d      1.855      0.53     -91   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        21
#  comp.  1:       -75        59
#  comp.  2:       -89        95
# chi2/DOF: 1.001; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8204      0.36     -75    59
# Comp:  1                Halpha      3.715      0.36     -75    59
# Comp:  2             [SII]6716      2.086      0.41     -89    95
# Comp:  2             [SII]6731     0.8197      0.41     -89    95
# Comp:  2              HeII4687    0.03978      0.41     -89    95
# Comp:  2               HeI5876      0.000      0.41     -89    95
# Comp:  2          [OIII]5007_d      1.344      0.51     -89    95
# Comp:  2            [OI]6300_d      1.086      0.51     -89    95
# Comp:  2           [NII]6583_d      1.828      0.51     -89    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -70        49
#  comp.  2:      -105        94
# chi2/DOF: 0.9948; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7132      0.34     -70    49
# Comp:  1                Halpha      3.217      0.34     -70    49
# Comp:  2             [SII]6716      2.064      0.40    -105    94
# Comp:  2             [SII]6731     0.9547      0.40    -105    94
# Comp:  2              HeII4687      0.000      0.40    -105    94
# Comp:  2               HeI5876     0.5683      0.40    -105    94
# Comp:  2          [OIII]5007_d      1.437      0.51    -105    94
# Comp:  2            [OI]6300_d     0.7197      0.51    -105    94
# Comp:  2           [NII]6583_d      1.541      0.51    -105    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -78        63
#  comp.  2:      -101       102
# chi2/DOF: 0.9984; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.158      0.36     -78    63
# Comp:  1                Halpha      3.598      0.36     -78    63
# Comp:  2             [SII]6716      2.127      0.42    -101   102
# Comp:  2             [SII]6731     0.9669      0.42    -101   102
# Comp:  2              HeII4687     0.3309      0.42    -101   102
# Comp:  2               HeI5876     0.6207      0.42    -101   102
# Comp:  2          [OIII]5007_d      1.164      0.53    -101   102
# Comp:  2            [OI]6300_d     0.9106      0.53    -101   102
# Comp:  2           [NII]6583_d      1.215      0.53    -101   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        48
#  comp.  1:       -77        63
#  comp.  2:       -83       108
# chi2/DOF: 0.9983; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.098      0.36     -77    63
# Comp:  1                Halpha      3.815      0.36     -77    63
# Comp:  2             [SII]6716      2.032      0.42     -83   108
# Comp:  2             [SII]6731      1.148      0.42     -83   108
# Comp:  2              HeII4687      0.000      0.42     -83   108
# Comp:  2               HeI5876     0.8808      0.42     -83   108
# Comp:  2          [OIII]5007_d      1.929      0.54     -83   108
# Comp:  2            [OI]6300_d      1.038      0.54     -83   108
# Comp:  2           [NII]6583_d      1.503      0.54     -83   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        29
#  comp.  1:       -79        57
#  comp.  2:      -108        83
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6691      0.35     -79    57
# Comp:  1                Halpha      3.455      0.35     -79    57
# Comp:  2             [SII]6716      2.104      0.39    -108    83
# Comp:  2             [SII]6731     0.8995      0.39    -108    83
# Comp:  2              HeII4687     0.2042      0.39    -108    83
# Comp:  2               HeI5876      0.000      0.39    -108    83
# Comp:  2          [OIII]5007_d      1.656      0.49    -108    83
# Comp:  2            [OI]6300_d      1.012      0.49    -108    83
# Comp:  2           [NII]6583_d      1.554      0.49    -108    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        39
#  comp.  1:       -83        61
#  comp.  2:      -119        89
# chi2/DOF: 1.002; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.351      0.36     -83    61
# Comp:  1                Halpha      3.968      0.36     -83    61
# Comp:  2             [SII]6716      1.827      0.40    -119    89
# Comp:  2             [SII]6731     0.9689      0.40    -119    89
# Comp:  2              HeII4687      0.000      0.40    -119    89
# Comp:  2               HeI5876     0.2566      0.40    -119    89
# Comp:  2          [OIII]5007_d      1.723      0.50    -119    89
# Comp:  2            [OI]6300_d     0.8098      0.50    -119    89
# Comp:  2           [NII]6583_d      1.251      0.50    -119    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -80        59
#  comp.  2:       -96        75
# chi2/DOF: 0.9976; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.810      0.36     -80    59
# Comp:  1                Halpha      4.241      0.36     -80    59
# Comp:  2             [SII]6716      1.761      0.38     -96    75
# Comp:  2             [SII]6731     0.9076      0.38     -96    75
# Comp:  2              HeII4687      0.000      0.38     -96    75
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8259      0.34     -75    51
# Comp:  1                Halpha      3.257      0.34     -75    51
# Comp:  2             [SII]6716      1.770      0.43     -74   109
# Comp:  2             [SII]6731     0.9407      0.43     -74   109
# Comp:  2              HeII4687     0.2827      0.43     -74   109
# Comp:  2               HeI5876      0.000      0.43     -74   109
# Comp:  2          [OIII]5007_d      1.656      0.54     -74   109
# Comp:  2            [OI]6300_d      1.226      0.54     -74   109
# Comp:  2           [NII]6583_d      1.272      0.54     -74   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -80        59
#  comp.  2:       -95        89
# chi2/DOF: 1.002; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6794      0.36     -80    59
# Comp:  1                Halpha      3.521      0.36     -80    59
# Comp:  2             [SII]6716      2.265      0.40     -95    89
# Comp:  2             [SII]6731     0.8938      0.40     -95    89
# Comp:  2              HeII4687     0.4580      0.40     -95    89
# Comp:  2               HeI5876     0.1216      0.40     -95    89
# Comp:  2          [OIII]5007_d      1.454      0.50     -95    89
# Comp:  2            [OI]6300_d      1.195      0.50     -95    89
# Comp:  2           [NII]6583_d      1.472      0.50     -95    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -65        61
#  comp.  2:       -82       100
# chi2/DOF: 0.9990; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.446      0.36     -65    61
# Comp:  1                Halpha      4.020      0.36     -65    61
# Comp:  2             [SII]6716      2.069      0.41     -82   100
# Comp:  2             [SII]6731      1.122      0.41     -82   100
# Comp:  2              HeII4687      0.000      0.41     -82   100
# Comp:  2               HeI5876    0.08904      0.41     -82   100
# Comp:  2          [OIII]5007_d      1.915      0.52     -82   100
# Comp:  2            [OI]6300_d      1.123      0.52     -82   100
# Comp:  2           [NII]6583_d      1.408      0.52     -82   100
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        49
#  comp.  1:       -62        69
#  comp.  2:       -85       106
# chi2/DOF: 0.9991; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.449      0.37     -62    69
# Comp:  1                Halpha      3.499      0.37     -62    69
# Comp:  2             [SII]6716      1.764      0.42     -85   106
# Comp:  2             [SII]6731     0.8854      0.42     -85   106
# Comp:  2              HeII4687     0.4548      0.42     -85   106
# Comp:  2               HeI5876     0.9226      0.42     -85   106
# Comp:  2          [OIII]5007_d     0.8915      0.53     -85   106
# Comp:  2            [OI]6300_d      1.256      0.53     -85   106
# Comp:  2           [NII]6583_d      1.854      0.53     -85   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -62        64
#  comp.  2:       -93       122
# chi2/DOF: 0.9995; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.026      0.36     -62    64
# Comp:  1                Halpha      3.719      0.36     -62    64
# Comp:  2             [SII]6716      2.238      0.44     -93   122
# Comp:  2             [SII]6731     0.9514      0.44     -93   122
# Comp:  2              HeII4687     0.3522      0.44     -93   122
# Comp:  2               HeI5876      0.000      0.44     -93   122
# Comp:  2          [OIII]5007_d      1.636      0.56     -93   122
# Comp:  2            [OI]6300_d      1.005      0.56     -93   122
# Comp:  2           [NII]6583_d      1.664      0.56     -93   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87         1
#  comp.  1:       -79        55
#  comp.  2:      -104        78
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5859      0.35     -79    55
# Comp:  1                Halpha      3.682      0.35     -79    55
# Comp:  2             [SII]6716      1.933      0.38    -104    78
# Comp:  2             [SII]6731     0.8559      0.38    -104    78
# Comp:  2              HeII4687      0.000      0.38    -104    78
# Comp:  2               HeI5876     0.2859      0.38    -104    78
# Comp:  2          [OIII]5007_d      1.842      0.48    -104    78
# Comp:  2            [OI]6300_d     0.8176      0.48    -104    78
# Comp:  2           [NII]6583_d      1.085      0.48    -104    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        43
#  comp.  1:       -63        63
#  comp.  2:       -94       107
# chi2/DOF: 0.9992; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.047      0.36     -63    63
# Comp:  1                Halpha      3.483      0.36     -63    63
# Comp:  2             [SII]6716      2.086      0.42     -94   107
# Comp:  2             [SII]6731     0.8758      0.42     -94   107
# Comp:  2              HeII4687     0.5738      0.42     -94   107
# Comp:  2               HeI5876     0.5563      0.42     -94   107
# Comp:  2          [OIII]5007_d      2.278      0.53     -94   107
# Comp:  2            [OI]6300_d     0.5883      0.53     -94   107
# Comp:  2           [NII]6583_d      1.884      0.53     -94   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -66        42
#  comp.  2:      -100        88
# chi2/DOF: 0.9999; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9363      0.33     -66    42
# Comp:  1                Halpha      3.337      0.33     -66    42
# Comp:  2             [SII]6716      1.753      0.40    -100    88
# Comp:  2             [SII]6731      1.002      0.40    -100    88
# Comp:  2              HeII4687     0.3096      0.40    -100    88
# Comp:  2               HeI5876     0.4865      0.40    -100    88
# Comp:  2          [OIII]5007_d      1.591      0.50    -100    88
# Comp:  2            [OI]6300_d     0.8227      0.50    -100    88
# Comp:  2           [NII]6583_d      1.884      0.50    -100    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        30
#  comp.  1:       -66        64
#  comp.  2:       -58       145
# chi2/DOF: 0.9977; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9899      0.36     -66    64
# Comp:  1                Halpha      3.709      0.36     -66    64
# Comp:  2             [SII]6716      2.283      0.48     -58   145
# Comp:  2             [SII]6731      1.189      0.48     -58   145
# Comp:  2              HeII4687     0.1509      0.48     -58   145
# Comp:  2               HeI5876      0.000      0.48     -58   145
# Comp:  2          [OIII]5007_d      1.361      0.60     -58   145
# Comp:  2            [OI]6300_d      1.864      0.60     -58   145
# Comp:  2           [NII]6583_d      2.200      0.60     -58   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        56
#  comp.  1:       -64        54
#  comp.  2:      -108        72
# chi2/DOF: 0.9961; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6026      0.35     -64    54
# Comp:  1                Halpha      3.408      0.35     -64    54
# Comp:  2             [SII]6716      1.811      0.37    -108    72
# Comp:  2             [SII]6731     0.9156      0.37    -108    72
# Comp:  2              HeII4687     0.2665      0.37    -108    72
# Comp:  2               HeI5876      0.000      0.37    -108    72
# Comp:  2          [OIII]5007_d     0.6715      0.47    -108    72
# Comp:  2            [OI]6300_d      1.201      0.47    -108    72
# Comp:  2           [NII]6583_d      1.087      0.47    -108    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -68        56
#  comp.  2:      -106       100
# chi2/DOF: 0.9977; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.386      0.35     -68    56
# Comp:  1                Halpha      3.559      0.35     -68    56
# Comp:  2             [SII]6716      2.127      0.41    -106   100
# Comp:  2             [SII]6731     0.9948      0.41    -106   100
# Comp:  2              HeII4687      0.000      0.41    -106   100
# Comp:  2               HeI5876      0.000      0.41    -106   100
# Comp:  2          [OIII]5007_d      1.420      0.52    -106   100
# Comp:  2            [OI]6300_d      1.312      0.52    -106   100
# Comp:  2           [NII]6583_d      1.323      0.52    -106   100
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -64        47
#  comp.  2:       -97       118
# chi2/DOF: 0.9981; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.217      0.34     -64    47
# Comp:  1                Halpha      3.591      0.34     -64    47
# Comp:  2             [SII]6716      2.329      0.44     -97   118
# Comp:  2             [SII]6731      1.128      0.44     -97   118
# Comp:  2              HeII4687     0.7592      0.44     -97   118
# Comp:  2               HeI5876      0.000      0.44     -97   118
# Comp:  2          [OIII]5007_d      1.622      0.55     -97   118
# Comp:  2            [OI]6300_d     0.8823      0.55     -97   118
# Comp:  2           [NII]6583_d      1.906      0.55     -97   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        42
#  comp.  1:       -70        60
#  comp.  2:       -69        84
# chi2/DOF: 0.9999; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.126      0.36     -70    60
# Comp:  1                Halpha      3.820      0.36     -70    60
# Comp:  2             [SII]6716      2.023      0.39     -69    84
# Comp:  2             [SII]6731      1.133      0.39     -69    84
# Comp:  2              HeII4687     0.1490      0.39     -69    84
# Comp:  2               HeI5876   0.009464      0.39     -69    84
# Comp:  2          [OIII]5007_d      1.702      0.49     -69    84
# Comp:  2            [OI]6300_d     0.9348      0.49     -69    84
# Comp:  2           [NII]6583_d      1.318      0.49     -69    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       -65        54
#  comp.  2:       -77        94
# chi2/DOF: 1.000; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.245      0.35     -65    54
# Comp:  1                Halpha      3.948      0.35     -65    54
# Comp:  2             [SII]6716      2.014      0.41     -77    94
# Comp:  2             [SII]6731      1.057      0.41     -77    94
# Comp:  2              HeII4687      0.000      0.41     -77    94
# Comp:  2               HeI5876     0.1337      0.41     -77    94
# Comp:  2          [OIII]5007_d      1.520      0.51     -77    94
# Comp:  2            [OI]6300_d      1.065      0.51     -77    94
# Comp:  2           [NII]6583_d      1.154      0.51     -77    94
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.33801797, 0.31546958, 0.28433511, 0.17483634, 0.23071651,
#        0.3470054 , 0.46475924, 0.31753558, 0.37380327])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.86597073, 4.82847095, 2.71913649, 1.34086514, 0.09159795,
#        0.09183051, 1.40224347, 1.16981764, 1.96961284])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.032851    0.012823
# 1        Halpha  0.183171    0.011968
# 2     [SII]6716  0.103152    0.010786
# 3     [SII]6731  0.050867    0.006633
# 4      HeII4687  0.003475    0.008752
# 5       HeI5876  0.003484    0.013164
# 6  [OIII]5007_d  0.053195    0.017631
# 7    [OI]6300_d  0.044378    0.012046
# 8   [NII]6583_d  0.074719    0.014180
#           Name      Flux  Error_flux
# 0        Hbeta  0.032851    0.012823
# 1       Halpha  0.183171    0.011968
# 2    [SII]6716  0.103152    0.010786
# 3    [SII]6731  0.050867    0.006633
# 4     HeII4687  0.003475    0.008752
# 5      HeI5876  0.003484    0.013164
# 6   [OIII]4959  0.013299    0.017631
# 7   [OIII]5007  0.039896    0.017631
# 8     [OI]6300  0.033283    0.012046
# 9     [OI]6364  0.011094    0.012046
# 10   [NII]6548  0.018680    0.014180
# 11   [NII]6583  0.056039    0.014180

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03793568565315615
