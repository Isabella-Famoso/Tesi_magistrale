# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00153

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22318852 2.22392739 2.22466626 ... 3.54133176 3.54207063 3.5428095 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
# chi2/DOF: 0.02265; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
# chi2/DOF: 0.01517; DOF: 1916; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([39.95264817,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        44         1
#  comp.  1:        34        72
#  comp.  2:       -24         1
# chi2/DOF: 2.370; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.666      0.33      34    72
# Comp:  1                Halpha      19.66      0.33      34    72
# Comp:  2             [SII]6716      3.641      0.27     -24     1
# Comp:  2             [SII]6731      126.8      0.27     -24     1
# Comp:  2              HeII4687     0.1408      0.27     -24     1
# Comp:  2               HeI5876    0.06646      0.27     -24     1
# Comp:  2          [OIII]5007_d      4.767      0.34     -24     1
# Comp:  2            [OI]6300_d      1.567      0.34     -24     1
# Comp:  2           [NII]6583_d      1.752      0.34     -24     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  10.72; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  36.78; gas flux:     27 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.529; gas flux:      5 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  350.8; gas flux:    178 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.3915; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.1868; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  10.25; gas flux:      5 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.325; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.492; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        45        56
#  comp.  1:        34        72
#  comp.  2:       -24         1
# chi2/DOF: 2.358; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.254      0.33      34    72
# Comp:  1                Halpha      19.54      0.33      34    72
# Comp:  2             [SII]6716      3.562      0.27     -24     1
# Comp:  2             [SII]6731      127.0      0.27     -24     1
# Comp:  2              HeII4687    0.06444      0.27     -24     1
# Comp:  2               HeI5876      0.000      0.27     -24     1
# Comp:  2          [OIII]5007_d      5.200      0.34     -24     1
# Comp:  2            [OI]6300_d      1.695      0.34     -24     1
# Comp:  2           [NII]6583_d      1.624      0.34     -24     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        30        65
#  comp.  2:       -30         1
# chi2/DOF: 1.767; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.360      0.32      30    65
# Comp:  1                Halpha      19.44      0.32      30    65
# Comp:  2             [SII]6716      3.748      0.27     -30     1
# Comp:  2             [SII]6731      131.0      0.27     -30     1
# Comp:  2              HeII4687     0.3774      0.27     -30     1
# Comp:  2               HeI5876    0.06661      0.27     -30     1
# Comp:  2          [OIII]5007_d      4.559      0.34     -30     1
# Comp:  2            [OI]6300_d      1.337      0.34     -30     1
# Comp:  2           [NII]6583_d      1.938      0.34     -30     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        29        68
#  comp.  2:       -16         1
# chi2/DOF: 1.539; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.506      0.33      29    68
# Comp:  1                Halpha      19.44      0.33      29    68
# Comp:  2             [SII]6716      3.205      0.27     -16     1
# Comp:  2             [SII]6731      130.6      0.27     -16     1
# Comp:  2              HeII4687     0.2532      0.27     -16     1
# Comp:  2               HeI5876    0.03416      0.27     -16     1
# Comp:  2          [OIII]5007_d      5.550      0.34     -16     1
# Comp:  2            [OI]6300_d      1.493      0.34     -16     1
# Comp:  2           [NII]6583_d      2.062      0.34     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45        13
#  comp.  1:        37        74
#  comp.  2:       -17         1
# chi2/DOF: 1.630; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.126      0.33      37    74
# Comp:  1                Halpha      20.44      0.33      37    74
# Comp:  2             [SII]6716      4.692      0.27     -17     1
# Comp:  2             [SII]6731      132.5      0.27     -17     1
# Comp:  2              HeII4687     0.3512      0.27     -17     1
# Comp:  2               HeI5876     0.1059      0.27     -17     1
# Comp:  2          [OIII]5007_d      4.126      0.34     -17     1
# Comp:  2            [OI]6300_d      1.930      0.34     -17     1
# Comp:  2           [NII]6583_d      1.928      0.34     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        81
#  comp.  1:        32        69
#  comp.  2:       -26        29
# chi2/DOF: 1.855; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.976      0.33      32    69
# Comp:  1                Halpha      19.01      0.33      32    69
# Comp:  2             [SII]6716      4.751      0.28     -26    29
# Comp:  2             [SII]6731      134.4      0.28     -26    29
# Comp:  2              HeII4687     0.3540      0.28     -26    29
# Comp:  2               HeI5876    0.07156      0.28     -26    29
# Comp:  2          [OIII]5007_d      3.800      0.36     -26    29
# Comp:  2            [OI]6300_d      2.102      0.36     -26    29
# Comp:  2           [NII]6583_d      2.096      0.36     -26    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67         1
#  comp.  1:        37        69
#  comp.  2:       -17         1
# chi2/DOF: 1.634; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.019      0.33      37    69
# Comp:  1                Halpha      20.10      0.33      37    69
# Comp:  2             [SII]6716      4.062      0.27     -17     1
# Comp:  2             [SII]6731      132.5      0.27     -17     1
# Comp:  2              HeII4687    0.01800      0.27     -17     1
# Comp:  2               HeI5876     0.2697      0.27     -17     1
# Comp:  2          [OIII]5007_d      4.684      0.34     -17     1
# Comp:  2            [OI]6300_d      1.684      0.34     -17     1
# Comp:  2           [NII]6583_d      1.438      0.34     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        81         1
#  comp.  1:        36        76
#  comp.  2:       -18         1
# chi2/DOF: 1.892; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.394      0.34      36    76
# Comp:  1                Halpha      19.62      0.34      36    76
# Comp:  2             [SII]6716      3.663      0.27     -18     1
# Comp:  2             [SII]6731      122.8      0.27     -18     1
# Comp:  2              HeII4687      0.000      0.27     -18     1
# Comp:  2               HeI5876    0.08541      0.27     -18     1
# Comp:  2          [OIII]5007_d      4.490      0.34     -18     1
# Comp:  2            [OI]6300_d      1.867      0.34     -18     1
# Comp:  2           [NII]6583_d      1.527      0.34     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         1
#  comp.  1:        34        72
#  comp.  2:       -23         1
# chi2/DOF: 2.292; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.605      0.33      34    72
# Comp:  1                Halpha      20.53      0.33      34    72
# Comp:  2             [SII]6716      4.356      0.27     -23     1
# Comp:  2             [SII]6731      124.9      0.27     -23     1
# Comp:  2              HeII4687     0.3190      0.27     -23     1
# Comp:  2               HeI5876     0.1664      0.27     -23     1
# Comp:  2          [OIII]5007_d      4.747      0.34     -23     1
# Comp:  2            [OI]6300_d      1.844      0.34     -23     1
# Comp:  2           [NII]6583_d      1.771      0.34     -23     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47        37
#  comp.  1:        31        72
#  comp.  2:       -20         1
# chi2/DOF: 2.133; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.021      0.33      31    72
# Comp:  1                Halpha      19.40      0.33      31    72
# Comp:  2             [SII]6716      3.656      0.27     -20     1
# Comp:  2             [SII]6731      124.8      0.27     -20     1
# Comp:  2              HeII4687     0.1593      0.27     -20     1
# Comp:  2               HeI5876    0.03036      0.27     -20     1
# Comp:  2          [OIII]5007_d      4.770      0.34     -20     1
# Comp:  2            [OI]6300_d      1.791      0.34     -20     1
# Comp:  2           [NII]6583_d      1.683      0.34     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        37        76
#  comp.  2:       -23        27
# chi2/DOF: 1.520; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.652      0.34      37    76
# Comp:  1                Halpha      20.16      0.34      37    76
# Comp:  2             [SII]6716      3.567      0.28     -23    27
# Comp:  2             [SII]6731      141.2      0.28     -23    27
# Comp:  2              HeII4687    0.05715      0.28     -23    27
# Comp:  2               HeI5876     0.2839      0.28     -23    27
# Comp:  2          [OIII]5007_d      3.902      0.36     -23    27
# Comp:  2            [OI]6300_d      2.012      0.36     -23    27
# Comp:  2           [NII]6583_d      1.861      0.36     -23    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:        31        65
#  comp.  2:       -17         1
# chi2/DOF: 1.742; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.698      0.32      31    65
# Comp:  1                Halpha      19.10      0.32      31    65
# Comp:  2             [SII]6716      4.120      0.27     -17     1
# Comp:  2             [SII]6731      130.2      0.27     -17     1
# Comp:  2              HeII4687   0.004627      0.27     -17     1
# Comp:  2               HeI5876     0.1811      0.27     -17     1
# Comp:  2          [OIII]5007_d      4.891      0.34     -17     1
# Comp:  2            [OI]6300_d      1.436      0.34     -17     1
# Comp:  2           [NII]6583_d      2.050      0.34     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        37
#  comp.  1:        30        70
#  comp.  2:       -22        30
# chi2/DOF: 1.557; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.862      0.33      30    70
# Comp:  1                Halpha      19.42      0.33      30    70
# Comp:  2             [SII]6716      4.362      0.28     -22    30
# Comp:  2             [SII]6731      140.5      0.28     -22    30
# Comp:  2              HeII4687    0.09010      0.28     -22    30
# Comp:  2               HeI5876      0.000      0.28     -22    30
# Comp:  2          [OIII]5007_d      5.073      0.36     -22    30
# Comp:  2            [OI]6300_d      1.708      0.36     -22    30
# Comp:  2           [NII]6583_d      1.255      0.36     -22    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        87        52
#  comp.  1:        39        79
#  comp.  2:       -25        29
# chi2/DOF: 1.889; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.144      0.34      39    79
# Comp:  1                Halpha      20.35      0.34      39    79
# Comp:  2             [SII]6716      4.956      0.28     -25    29
# Comp:  2             [SII]6731      132.5      0.28     -25    29
# Comp:  2              HeII4687      0.000      0.28     -25    29
# Comp:  2               HeI5876      0.000      0.28     -25    29
# Comp:  2          [OIII]5007_d      5.417      0.36     -25    29
# Comp:  2            [OI]6300_d      1.386      0.36     -25    29
# Comp:  2           [NII]6583_d      2.082      0.36     -25    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        62        49
#  comp.  1:        34        77
#  comp.  2:       -23        21
# chi2/DOF: 1.935; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.614      0.34      34    77
# Comp:  1                Halpha      21.00      0.34      34    77
# Comp:  2             [SII]6716      3.481      0.28     -23    21
# Comp:  2             [SII]6731      136.8      0.28     -23    21
# Comp:  2              HeII4687     0.1910      0.28     -23    21
# Comp:  2               HeI5876    0.01831      0.28     -23    21
# Comp:  2          [OIII]5007_d      4.022      0.35     -23    21
# Comp:  2            [OI]6300_d      1.526      0.35     -23    21
# Comp:  2           [NII]6583_d      1.981      0.35     -23    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        70       122
#  comp.  1:        32        73
#  comp.  2:       -32        25
# chi2/DOF: 1.413; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.959      0.33      32    73
# Comp:  1                Halpha      19.53      0.33      32    73
# Comp:  2             [SII]6716      3.895      0.28     -32    25
# Comp:  2             [SII]6731      128.7      0.28     -32    25
# Comp:  2              HeII4687     0.2331      0.28     -32    25
# Comp:  2               HeI5876      0.000      0.28     -32    25
# Comp:  2          [OIII]5007_d      3.990      0.36     -32    25
# Comp:  2            [OI]6300_d      1.380      0.36     -32    25
# Comp:  2           [NII]6583_d      1.691      0.36     -32    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:        32        68
#  comp.  2:       -17         9
# chi2/DOF: 1.772; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.027      0.33      32    68
# Comp:  1                Halpha      19.15      0.33      32    68
# Comp:  2             [SII]6716      4.138      0.27     -17     9
# Comp:  2             [SII]6731      123.9      0.27     -17     9
# Comp:  2              HeII4687     0.1700      0.27     -17     9
# Comp:  2               HeI5876      0.000      0.27     -17     9
# Comp:  2          [OIII]5007_d      5.192      0.35     -17     9
# Comp:  2            [OI]6300_d      1.365      0.35     -17     9
# Comp:  2           [NII]6583_d      2.165      0.35     -17     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        48
#  comp.  1:        31        73
#  comp.  2:       -22         1
# chi2/DOF: 2.278; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.658      0.33      31    73
# Comp:  1                Halpha      20.16      0.33      31    73
# Comp:  2             [SII]6716      3.748      0.27     -22     1
# Comp:  2             [SII]6731      125.3      0.27     -22     1
# Comp:  2              HeII4687     0.2183      0.27     -22     1
# Comp:  2               HeI5876     0.1119      0.27     -22     1
# Comp:  2          [OIII]5007_d      4.649      0.34     -22     1
# Comp:  2            [OI]6300_d      1.548      0.34     -22     1
# Comp:  2           [NII]6583_d      1.713      0.34     -22     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        32        68
#  comp.  2:       -22        30
# chi2/DOF: 1.536; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.972      0.33      32    68
# Comp:  1                Halpha      18.91      0.33      32    68
# Comp:  2             [SII]6716      4.438      0.29     -22    30
# Comp:  2             [SII]6731      140.6      0.29     -22    30
# Comp:  2              HeII4687   0.004373      0.29     -22    30
# Comp:  2               HeI5876      0.000      0.29     -22    30
# Comp:  2          [OIII]5007_d      4.460      0.36     -22    30
# Comp:  2            [OI]6300_d      1.697      0.36     -22    30
# Comp:  2           [NII]6583_d      1.342      0.36     -22    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        30        74
#  comp.  2:       -18         1
# chi2/DOF: 1.809; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.312      0.33      30    74
# Comp:  1                Halpha      19.53      0.33      30    74
# Comp:  2             [SII]6716      3.194      0.27     -18     1
# Comp:  2             [SII]6731      132.0      0.27     -18     1
# Comp:  2              HeII4687     0.3211      0.27     -18     1
# Comp:  2               HeI5876    0.03810      0.27     -18     1
# Comp:  2          [OIII]5007_d      4.651      0.34     -18     1
# Comp:  2            [OI]6300_d      1.532      0.34     -18     1
# Comp:  2           [NII]6583_d      2.142      0.34     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:        34        73
#  comp.  2:       -28         1
# chi2/DOF: 2.084; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.117      0.33      34    73
# Comp:  1                Halpha      19.36      0.33      34    73
# Comp:  2             [SII]6716      2.875      0.27     -28     1
# Comp:  2             [SII]6731      128.7      0.27     -28     1
# Comp:  2              HeII4687     0.3281      0.27     -28     1
# Comp:  2               HeI5876      0.000      0.27     -28     1
# Comp:  2          [OIII]5007_d      4.855      0.34     -28     1
# Comp:  2            [OI]6300_d      1.498      0.34     -28     1
# Comp:  2           [NII]6583_d      1.655      0.34     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46        74
#  comp.  1:        33        70
#  comp.  2:       -28         1
# chi2/DOF: 2.082; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.762      0.33      33    70
# Comp:  1                Halpha      19.64      0.33      33    70
# Comp:  2             [SII]6716      4.703      0.27     -28     1
# Comp:  2             [SII]6731      128.6      0.27     -28     1
# Comp:  2              HeII4687    0.06561      0.27     -28     1
# Comp:  2               HeI5876    0.06835      0.27     -28     1
# Comp:  2          [OIII]5007_d      4.365      0.34     -28     1
# Comp:  2            [OI]6300_d      1.670      0.34     -28     1
# Comp:  2           [NII]6583_d      1.527      0.34     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:        30        69
#  comp.  2:       -32        21
# chi2/DOF: 1.586; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.319      0.33      30    69
# Comp:  1                Halpha      19.52      0.33      30    69
# Comp:  2             [SII]6716      3.681      0.28     -32    21
# Comp:  2             [SII]6731      127.4      0.28     -32    21
# Comp:  2              HeII4687    0.03027      0.28     -32    21
# Comp:  2               HeI5876     0.1999      0.28     -32    21
# Comp:  2          [OIII]5007_d      4.935      0.35     -32    21
# Comp:  2            [OI]6300_d      1.628      0.35     -32    21
# Comp:  2           [NII]6583_d      2.076      0.35     -32    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       104        19
#  comp.  1:        40        75
#  comp.  2:       -29         8
# chi2/DOF: 1.924; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.367      0.33      40    75
# Comp:  1                Halpha      20.20      0.33      40    75
# Comp:  2             [SII]6716      4.377      0.27     -29     8
# Comp:  2             [SII]6731      131.6      0.27     -29     8
# Comp:  2              HeII4687     0.1387      0.27     -29     8
# Comp:  2               HeI5876     0.1034      0.27     -29     8
# Comp:  2          [OIII]5007_d      4.748      0.34     -29     8
# Comp:  2            [OI]6300_d      1.944      0.34     -29     8
# Comp:  2           [NII]6583_d      1.654      0.34     -29     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69        51
#  comp.  1:        38        80
#  comp.  2:       -26        36
# chi2/DOF: 1.360; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.433      0.34      38    80
# Comp:  1                Halpha      21.36      0.34      38    80
# Comp:  2             [SII]6716      3.678      0.29     -26    36
# Comp:  2             [SII]6731      138.4      0.29     -26    36
# Comp:  2              HeII4687    0.03835      0.29     -26    36
# Comp:  2               HeI5876      0.000      0.29     -26    36
# Comp:  2          [OIII]5007_d      4.967      0.37     -26    36
# Comp:  2            [OI]6300_d      1.773      0.37     -26    36
# Comp:  2           [NII]6583_d      2.333      0.37     -26    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:        38        78
#  comp.  2:       -25        29
# chi2/DOF: 1.898; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.003      0.34      38    78
# Comp:  1                Halpha      20.43      0.34      38    78
# Comp:  2             [SII]6716      3.936      0.28     -25    29
# Comp:  2             [SII]6731      132.4      0.28     -25    29
# Comp:  2              HeII4687      0.000      0.28     -25    29
# Comp:  2               HeI5876     0.2327      0.28     -25    29
# Comp:  2          [OIII]5007_d      4.952      0.36     -25    29
# Comp:  2            [OI]6300_d      1.635      0.36     -25    29
# Comp:  2           [NII]6583_d      2.236      0.36     -25    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20        85
#  comp.  1:        32        71
#  comp.  2:       -32        21
# chi2/DOF: 1.567; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.192      0.33      32    71
# Comp:  1                Halpha      19.19      0.33      32    71
# Comp:  2             [SII]6716      3.442      0.28     -32    21
# Comp:  2             [SII]6731      127.3      0.28     -32    21
# Comp:  2              HeII4687      0.000      0.28     -32    21
# Comp:  2               HeI5876     0.1737      0.28     -32    21
# Comp:  2          [OIII]5007_d      5.107      0.35     -32    21
# Comp:  2            [OI]6300_d      1.753      0.35     -32    21
# Comp:  2           [NII]6583_d      2.273      0.35     -32    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        36        79
#  comp.  2:       -24         1
# chi2/DOF: 2.348; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.658      0.34      36    79
# Comp:  1                Halpha      20.51      0.34      36    79
# Comp:  2             [SII]6716      4.393      0.27     -24     1
# Comp:  2             [SII]6731      127.0      0.27     -24     1
# Comp:  2              HeII4687     0.3231      0.27     -24     1
# Comp:  2               HeI5876    0.03405      0.27     -24     1
# Comp:  2          [OIII]5007_d      5.011      0.34     -24     1
# Comp:  2            [OI]6300_d      1.932      0.34     -24     1
# Comp:  2           [NII]6583_d      1.542      0.34     -24     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        70        51
#  comp.  1:        35        76
#  comp.  2:       -18         1
# chi2/DOF: 1.938; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.647      0.34      35    76
# Comp:  1                Halpha      19.83      0.34      35    76
# Comp:  2             [SII]6716      3.850      0.27     -18     1
# Comp:  2             [SII]6731      122.9      0.27     -18     1
# Comp:  2              HeII4687     0.1778      0.27     -18     1
# Comp:  2               HeI5876      0.000      0.27     -18     1
# Comp:  2          [OIII]5007_d      5.548      0.34     -18     1
# Comp:  2            [OI]6300_d      1.336      0.34     -18     1
# Comp:  2           [NII]6583_d      2.373      0.34     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12         1
#  comp.  1:        31        62
#  comp.  2:       -28         1
# chi2/DOF: 2.088; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.797      0.32      31    62
# Comp:  1                Halpha      18.76      0.32      31    62
# Comp:  2             [SII]6716      3.925      0.27     -28     1
# Comp:  2             [SII]6731      128.6      0.27     -28     1
# Comp:  2              HeII4687      0.000      0.27     -28     1
# Comp:  2               HeI5876     0.1711      0.27     -28     1
# Comp:  2          [OIII]5007_d      5.414      0.34     -28     1
# Comp:  2            [OI]6300_d      1.812      0.34     -28     1
# Comp:  2           [NII]6583_d      1.980      0.34     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        46
#  comp.  1:        37        73
#  comp.  2:       -28        16
# chi2/DOF: 2.081; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.716      0.33      37    73
# Comp:  1                Halpha      20.43      0.33      37    73
# Comp:  2             [SII]6716      4.456      0.28     -28    16
# Comp:  2             [SII]6731      131.0      0.28     -28    16
# Comp:  2              HeII4687     0.2760      0.28     -28    16
# Comp:  2               HeI5876    0.01201      0.28     -28    16
# Comp:  2          [OIII]5007_d      3.934      0.35     -28    16
# Comp:  2            [OI]6300_d      1.892      0.35     -28    16
# Comp:  2           [NII]6583_d      1.375      0.35     -28    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        28
#  comp.  1:        35        72
#  comp.  2:       -24         1
# chi2/DOF: 1.849; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 76; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.660      0.33      35    72
# Comp:  1                Halpha      20.25      0.33      35    72
# Comp:  2             [SII]6716      4.006      0.27     -24     1
# Comp:  2             [SII]6731      117.7      0.27     -24     1
# Comp:  2              HeII4687      0.000      0.27     -24     1
# Comp:  2               HeI5876    0.02981      0.27     -24     1
# Comp:  2          [OIII]5007_d      4.264      0.34     -24     1
# Comp:  2            [OI]6300_d      1.909      0.34     -24     1
# Comp:  2           [NII]6583_d      1.593      0.34     -24     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        40
#  comp.  1:        34        70
#  comp.  2:       -27        32
# chi2/DOF: 1.659; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.214      0.33      34    70
# Comp:  1                Halpha      20.14      0.33      34    70
# Comp:  2             [SII]6716      3.041      0.29     -27    32
# Comp:  2             [SII]6731      135.8      0.29     -27    32
# Comp:  2              HeII4687    0.02164      0.29     -27    32
# Comp:  2               HeI5876     0.2591      0.29     -27    32
# Comp:  2          [OIII]5007_d      3.955      0.36     -27    32
# Comp:  2            [OI]6300_d      1.609      0.36     -27    32
# Comp:  2           [NII]6583_d      2.238      0.36     -27    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:        34        68
#  comp.  2:       -30        22
# chi2/DOF: 1.671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.059      0.33      34    68
# Comp:  1                Halpha      18.89      0.33      34    68
# Comp:  2             [SII]6716      4.576      0.28     -30    22
# Comp:  2             [SII]6731      125.6      0.28     -30    22
# Comp:  2              HeII4687     0.1062      0.28     -30    22
# Comp:  2               HeI5876   0.008151      0.28     -30    22
# Comp:  2          [OIII]5007_d      5.084      0.35     -30    22
# Comp:  2            [OI]6300_d      1.518      0.35     -30    22
# Comp:  2           [NII]6583_d      2.185      0.35     -30    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        74        78
#  comp.  1:        34        67
#  comp.  2:       -28         1
# chi2/DOF: 2.087; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.441      0.32      34    67
# Comp:  1                Halpha      18.83      0.32      34    67
# Comp:  2             [SII]6716      4.088      0.27     -28     1
# Comp:  2             [SII]6731      128.6      0.27     -28     1
# Comp:  2              HeII4687     0.2182      0.27     -28     1
# Comp:  2               HeI5876     0.1454      0.27     -28     1
# Comp:  2          [OIII]5007_d      5.098      0.34     -28     1
# Comp:  2            [OI]6300_d      1.647      0.34     -28     1
# Comp:  2           [NII]6583_d      1.964      0.34     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49       556
#  comp.  1:        29        68
#  comp.  2:       -18         1
# chi2/DOF: 1.853; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.832      0.33      29    68
# Comp:  1                Halpha      18.87      0.33      29    68
# Comp:  2             [SII]6716      4.051      0.27     -18     1
# Comp:  2             [SII]6731      132.2      0.27     -18     1
# Comp:  2              HeII4687     0.3525      0.27     -18     1
# Comp:  2               HeI5876     0.1271      0.27     -18     1
# Comp:  2          [OIII]5007_d      4.387      0.34     -18     1
# Comp:  2            [OI]6300_d      1.256      0.34     -18     1
# Comp:  2           [NII]6583_d      1.867      0.34     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50         1
#  comp.  1:        33        75
#  comp.  2:       -31        16
# chi2/DOF: 1.611; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.929      0.33      33    75
# Comp:  1                Halpha      19.35      0.33      33    75
# Comp:  2             [SII]6716      4.257      0.28     -31    16
# Comp:  2             [SII]6731      123.5      0.28     -31    16
# Comp:  2              HeII4687     0.1082      0.28     -31    16
# Comp:  2               HeI5876      0.000      0.28     -31    16
# Comp:  2          [OIII]5007_d      4.805      0.35     -31    16
# Comp:  2            [OI]6300_d      1.947      0.35     -31    16
# Comp:  2           [NII]6583_d      1.889      0.35     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65        19
#  comp.  1:        33        71
#  comp.  2:       -32        20
# chi2/DOF: 1.494; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.404      0.33      33    71
# Comp:  1                Halpha      19.41      0.33      33    71
# Comp:  2             [SII]6716      3.547      0.28     -32    20
# Comp:  2             [SII]6731      124.8      0.28     -32    20
# Comp:  2              HeII4687      0.000      0.28     -32    20
# Comp:  2               HeI5876     0.1655      0.28     -32    20
# Comp:  2          [OIII]5007_d      5.375      0.35     -32    20
# Comp:  2            [OI]6300_d      1.646      0.35     -32    20
# Comp:  2           [NII]6583_d      1.637      0.35     -32    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        51        67
#  comp.  1:        31        68
#  comp.  2:       -25         1
# chi2/DOF: 1.851; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.575      0.33      31    68
# Comp:  1                Halpha      19.58      0.33      31    68
# Comp:  2             [SII]6716      3.558      0.27     -25     1
# Comp:  2             [SII]6731      117.9      0.27     -25     1
# Comp:  2              HeII4687     0.3230      0.27     -25     1
# Comp:  2               HeI5876     0.2050      0.27     -25     1
# Comp:  2          [OIII]5007_d      4.390      0.34     -25     1
# Comp:  2            [OI]6300_d      1.393      0.34     -25     1
# Comp:  2           [NII]6583_d      2.082      0.34     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54         1
#  comp.  1:        32        72
#  comp.  2:       -25        30
# chi2/DOF: 1.889; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.454      0.33      32    72
# Comp:  1                Halpha      19.73      0.33      32    72
# Comp:  2             [SII]6716      3.495      0.28     -25    30
# Comp:  2             [SII]6731      132.5      0.28     -25    30
# Comp:  2              HeII4687  0.0007312      0.28     -25    30
# Comp:  2               HeI5876     0.1412      0.28     -25    30
# Comp:  2          [OIII]5007_d      5.617      0.36     -25    30
# Comp:  2            [OI]6300_d      1.522      0.36     -25    30
# Comp:  2           [NII]6583_d      1.774      0.36     -25    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63        84
#  comp.  1:        34        71
#  comp.  2:       -16         1
# chi2/DOF: 1.487; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.325      0.33      34    71
# Comp:  1                Halpha      20.11      0.33      34    71
# Comp:  2             [SII]6716      4.553      0.27     -16     1
# Comp:  2             [SII]6731      130.6      0.27     -16     1
# Comp:  2              HeII4687     0.1467      0.27     -16     1
# Comp:  2               HeI5876    0.06648      0.27     -16     1
# Comp:  2          [OIII]5007_d      5.602      0.34     -16     1
# Comp:  2            [OI]6300_d      1.185      0.34     -16     1
# Comp:  2           [NII]6583_d      1.452      0.34     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69        59
#  comp.  1:        38        80
#  comp.  2:       -23        21
# chi2/DOF: 1.944; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.711      0.34      38    80
# Comp:  1                Halpha      20.44      0.34      38    80
# Comp:  2             [SII]6716      3.573      0.28     -23    21
# Comp:  2             [SII]6731      136.8      0.28     -23    21
# Comp:  2              HeII4687    0.01802      0.28     -23    21
# Comp:  2               HeI5876    0.06258      0.28     -23    21
# Comp:  2          [OIII]5007_d      5.460      0.35     -23    21
# Comp:  2            [OI]6300_d      1.424      0.35     -23    21
# Comp:  2           [NII]6583_d      2.004      0.35     -23    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55         1
#  comp.  1:        33        70
#  comp.  2:       -30        23
# chi2/DOF: 1.665; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.668      0.33      33    70
# Comp:  1                Halpha      19.06      0.33      33    70
# Comp:  2             [SII]6716      3.304      0.28     -30    23
# Comp:  2             [SII]6731      125.7      0.28     -30    23
# Comp:  2              HeII4687      0.000      0.28     -30    23
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.575      0.33      29    73
# Comp:  1                Halpha      20.03      0.33      29    73
# Comp:  2             [SII]6716      3.005      0.29     -26    37
# Comp:  2             [SII]6731      138.5      0.29     -26    37
# Comp:  2              HeII4687      0.000      0.29     -26    37
# Comp:  2               HeI5876      0.000      0.29     -26    37
# Comp:  2          [OIII]5007_d      4.865      0.37     -26    37
# Comp:  2            [OI]6300_d      1.417      0.37     -26    37
# Comp:  2           [NII]6583_d      2.440      0.37     -26    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:        36        72
#  comp.  2:       -28        16
# chi2/DOF: 2.083; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.818      0.33      36    72
# Comp:  1                Halpha      20.08      0.33      36    72
# Comp:  2             [SII]6716      4.712      0.28     -28    16
# Comp:  2             [SII]6731      131.0      0.28     -28    16
# Comp:  2              HeII4687     0.1867      0.28     -28    16
# Comp:  2               HeI5876     0.1261      0.28     -28    16
# Comp:  2          [OIII]5007_d      4.978      0.35     -28    16
# Comp:  2            [OI]6300_d      1.248      0.35     -28    16
# Comp:  2           [NII]6583_d      2.026      0.35     -28    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24         1
#  comp.  1:        32        69
#  comp.  2:       -17        14
# chi2/DOF: 1.800; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.478      0.33      32    69
# Comp:  1                Halpha      19.00      0.33      32    69
# Comp:  2             [SII]6716      3.739      0.28     -17    14
# Comp:  2             [SII]6731      124.8      0.28     -17    14
# Comp:  2              HeII4687      0.000      0.28     -17    14
# Comp:  2               HeI5876      0.000      0.28     -17    14
# Comp:  2          [OIII]5007_d      5.288      0.35     -17    14
# Comp:  2            [OI]6300_d      1.559      0.35     -17    14
# Comp:  2           [NII]6583_d      1.796      0.35     -17    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:        36        73
#  comp.  2:       -31        16
# chi2/DOF: 1.608; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.519      0.33      36    73
# Comp:  1                Halpha      19.99      0.33      36    73
# Comp:  2             [SII]6716      2.928      0.28     -31    16
# Comp:  2             [SII]6731      123.5      0.28     -31    16
# Comp:  2              HeII4687     0.2002      0.28     -31    16
# Comp:  2               HeI5876     0.2685      0.28     -31    16
# Comp:  2          [OIII]5007_d      4.821      0.35     -31    16
# Comp:  2            [OI]6300_d      1.451      0.35     -31    16
# Comp:  2           [NII]6583_d      2.197      0.35     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        69
#  comp.  1:        31        70
#  comp.  2:       -23         1
# chi2/DOF: 2.348; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.899      0.33      31    70
# Comp:  1                Halpha      19.25      0.33      31    70
# Comp:  2             [SII]6716      3.992      0.27     -23     1
# Comp:  2             [SII]6731      127.3      0.27     -23     1
# Comp:  2              HeII4687     0.2686      0.27     -23     1
# Comp:  2               HeI5876      0.000      0.27     -23     1
# Comp:  2          [OIII]5007_d      4.688      0.34     -23     1
# Comp:  2            [OI]6300_d      1.915      0.34     -23     1
# Comp:  2           [NII]6583_d      1.652      0.34     -23     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35         1
#  comp.  1:        36        77
#  comp.  2:       -32        21
# chi2/DOF: 1.574; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.984      0.34      36    77
# Comp:  1                Halpha      20.73      0.34      36    77
# Comp:  2             [SII]6716      4.108      0.28     -32    21
# Comp:  2             [SII]6731      127.3      0.28     -32    21
# Comp:  2              HeII4687    0.08043      0.28     -32    21
# Comp:  2               HeI5876    0.02417      0.28     -32    21
# Comp:  2          [OIII]5007_d      5.657      0.35     -32    21
# Comp:  2            [OI]6300_d      1.784      0.35     -32    21
# Comp:  2           [NII]6583_d      1.610      0.35     -32    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        35        72
#  comp.  2:       -31        16
# chi2/DOF: 1.610; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.767      0.33      35    72
# Comp:  1                Halpha      19.41      0.33      35    72
# Comp:  2             [SII]6716      3.071      0.28     -31    16
# Comp:  2             [SII]6731      123.5      0.28     -31    16
# Comp:  2              HeII4687     0.2862      0.28     -31    16
# Comp:  2               HeI5876     0.1406      0.28     -31    16
# Comp:  2          [OIII]5007_d      5.843      0.35     -31    16
# Comp:  2            [OI]6300_d      1.698      0.35     -31    16
# Comp:  2           [NII]6583_d      1.871      0.35     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        10
#  comp.  1:        31        66
#  comp.  2:       -17         1
# chi2/DOF: 1.670; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.998      0.32      31    66
# Comp:  1                Halpha      19.56      0.32      31    66
# Comp:  2             [SII]6716      2.708      0.27     -17     1
# Comp:  2             [SII]6731      132.5      0.27     -17     1
# Comp:  2              HeII4687    0.03071      0.27     -17     1
# Comp:  2               HeI5876     0.1963      0.27     -17     1
# Comp:  2          [OIII]5007_d      5.300      0.34     -17     1
# Comp:  2            [OI]6300_d      1.689      0.34     -17     1
# Comp:  2           [NII]6583_d      1.576      0.34     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:        37        74
#  comp.  2:       -17         1
# chi2/DOF: 1.748; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.158      0.33      37    74
# Comp:  1                Halpha      19.65      0.33      37    74
# Comp:  2             [SII]6716      3.323      0.27     -17     1
# Comp:  2             [SII]6731      130.1      0.27     -17     1
# Comp:  2              HeII4687     0.2549      0.27     -17     1
# Comp:  2               HeI5876      0.000      0.27     -17     1
# Comp:  2          [OIII]5007_d      4.677      0.34     -17     1
# Comp:  2            [OI]6300_d      1.482      0.34     -17     1
# Comp:  2           [NII]6583_d      1.517      0.34     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        47
#  comp.  1:        28        70
#  comp.  2:       -27        32
# chi2/DOF: 1.663; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.718      0.33      28    70
# Comp:  1                Halpha      19.65      0.33      28    70
# Comp:  2             [SII]6716      4.445      0.29     -27    32
# Comp:  2             [SII]6731      135.8      0.29     -27    32
# Comp:  2              HeII4687      0.000      0.29     -27    32
# Comp:  2               HeI5876      0.000      0.29     -27    32
# Comp:  2          [OIII]5007_d      4.663      0.36     -27    32
# Comp:  2            [OI]6300_d      1.443      0.36     -27    32
# Comp:  2           [NII]6583_d      2.033      0.36     -27    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        17
#  comp.  1:        38        78
#  comp.  2:       -17        14
# chi2/DOF: 1.799; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.962      0.34      38    78
# Comp:  1                Halpha      20.20      0.34      38    78
# Comp:  2             [SII]6716      4.173      0.28     -17    14
# Comp:  2             [SII]6731      124.7      0.28     -17    14
# Comp:  2              HeII4687     0.2468      0.28     -17    14
# Comp:  2               HeI5876      0.000      0.28     -17    14
# Comp:  2          [OIII]5007_d      4.429      0.35     -17    14
# Comp:  2            [OI]6300_d      1.295      0.35     -17    14
# Comp:  2           [NII]6583_d      1.638      0.35     -17    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        79        45
#  comp.  1:        35        77
#  comp.  2:       -18         1
# chi2/DOF: 1.944; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.762      0.34      35    77
# Comp:  1                Halpha      19.71      0.34      35    77
# Comp:  2             [SII]6716      3.962      0.27     -18     1
# Comp:  2             [SII]6731      122.9      0.27     -18     1
# Comp:  2              HeII4687     0.2600      0.27     -18     1
# Comp:  2               HeI5876     0.1258      0.27     -18     1
# Comp:  2          [OIII]5007_d      4.271      0.34     -18     1
# Comp:  2            [OI]6300_d      1.376      0.34     -18     1
# Comp:  2           [NII]6583_d      1.403      0.34     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        61
#  comp.  1:        33        72
#  comp.  2:       -17         9
# chi2/DOF: 1.767; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.890      0.33      33    72
# Comp:  1                Halpha      20.48      0.33      33    72
# Comp:  2             [SII]6716      3.922      0.27     -17     9
# Comp:  2             [SII]6731      124.0      0.27     -17     9
# Comp:  2              HeII4687      0.000      0.27     -17     9
# Comp:  2               HeI5876    0.01087      0.27     -17     9
# Comp:  2          [OIII]5007_d      4.893      0.35     -17     9
# Comp:  2            [OI]6300_d      1.536      0.35     -17     9
# Comp:  2           [NII]6583_d      1.562      0.35     -17     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23        89
#  comp.  1:        30        76
#  comp.  2:       -25        33
# chi2/DOF: 1.588; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.617      0.34      30    76
# Comp:  1                Halpha      20.09      0.34      30    76
# Comp:  2             [SII]6716      3.313      0.29     -25    33
# Comp:  2             [SII]6731      136.9      0.29     -25    33
# Comp:  2              HeII4687     0.1912      0.29     -25    33
# Comp:  2               HeI5876      0.000      0.29     -25    33
# Comp:  2          [OIII]5007_d      5.431      0.36     -25    33
# Comp:  2            [OI]6300_d      1.861      0.36     -25    33
# Comp:  2           [NII]6583_d      1.738      0.36     -25    33
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.54232979, 0.73503461, 0.79831201, 9.05396985, 0.12048981,
#        0.09305823, 0.57339101, 0.28041141, 0.38143663])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([5.74516464e+00, 2.69059560e+01, 5.10114790e+00, 1.78048338e+02,
#        1.37627017e-01, 8.14468304e-02, 4.97793779e+00, 2.05967796e+00,
#        2.40508253e+00])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.245741    0.023197
# 1        Halpha  1.150861    0.031440
# 2     [SII]6716  0.218194    0.034147
# 3     [SII]6731  7.615747    0.387270
# 4      HeII4687  0.005887    0.005154
# 5       HeI5876  0.003484    0.003980
# 6  [OIII]5007_d  0.212924    0.024526
# 7    [OI]6300_d  0.088100    0.011994
# 8   [NII]6583_d  0.102874    0.016315
#           Name      Flux  Error_flux
# 0        Hbeta  0.245741    0.023197
# 1       Halpha  1.150861    0.031440
# 2    [SII]6716  0.218194    0.034147
# 3    [SII]6731  7.615747    0.387270
# 4     HeII4687  0.005887    0.005154
# 5      HeI5876  0.003484    0.003980
# 6   [OIII]4959  0.053231    0.024526
# 7   [OIII]5007  0.159693    0.024526
# 8     [OI]6300  0.066075    0.011994
# 9     [OI]6364  0.022025    0.011994
# 10   [NII]6548  0.025718    0.016315
# 11   [NII]6583  0.077155    0.016315

# %%
np.median(flux_rf_rebin)
# Out:
# 0.042773478618313036
