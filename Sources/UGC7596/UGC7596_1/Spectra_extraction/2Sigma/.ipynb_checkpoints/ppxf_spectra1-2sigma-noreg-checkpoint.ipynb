# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
# chi2/DOF: 0.009888; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
# chi2/DOF: 0.007437; DOF: 1912; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [0.91116313 0.96960163 1.05488085 ... 0.8673128  0.86253662 0.81198489]
# [1.02795375 1.03557064 1.03278045 ... 0.9262107  0.9185944  0.913542  ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-59.79526635,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        38
#  comp.  1:        20       180
#  comp.  2:        16       181
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.34      20   180
# Comp:  1                Halpha      0.000      0.34      20   180
# Comp:  2             [SII]6716     0.3876      0.34      16   181
# Comp:  2             [SII]6731      0.000      0.34      16   181
# Comp:  2              HeII4687     0.2163      0.34      16   181
# Comp:  2               HeI5876      0.000      0.34      16   181
# Comp:  2          [OIII]5007_d     0.3195      0.43      16   181
# Comp:  2            [OI]6300_d    0.06283      0.43      16   181
# Comp:  2           [NII]6583_d     0.3225      0.43      16   181
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.5609; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.3113; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.3447; gas flux:      0 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.06839; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.3514; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        49
#  comp.  1:      -137       224
#  comp.  2:        13        59
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9055      0.38    -137   224
# Comp:  1                Halpha     0.5342      0.38    -137   224
# Comp:  2             [SII]6716    0.04409      0.23      13    59
# Comp:  2             [SII]6731     0.3422      0.23      13    59
# Comp:  2              HeII4687     0.3966      0.23      13    59
# Comp:  2               HeI5876      0.000      0.23      13    59
# Comp:  2          [OIII]5007_d     0.2291      0.29      13    59
# Comp:  2            [OI]6300_d      0.000      0.29      13    59
# Comp:  2           [NII]6583_d      0.000      0.29      13    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        83
#  comp.  1:       213        21
#  comp.  2:      -678        35
# chi2/DOF: 0.9416; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3022      0.21     213    21
# Comp:  1                Halpha     0.3343      0.38     213    21
# Comp:  2             [SII]6716      0.000      0.21    -678    35
# Comp:  2             [SII]6731    0.02030      0.21    -678    35
# Comp:  2              HeII4687    0.02234      0.21    -678    35
# Comp:  2               HeI5876      0.000      0.21    -678    35
# Comp:  2          [OIII]5007_d      0.000      0.27    -678    35
# Comp:  2            [OI]6300_d      3.530      0.27    -678    35
# Comp:  2           [NII]6583_d      0.000      0.50    -678    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:      -188       286
#  comp.  2:       204         1
# chi2/DOF: 1.015; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9116      0.42    -188   286
# Comp:  1                Halpha     0.5383      0.43    -188   286
# Comp:  2             [SII]6716     0.3953      0.20     204     1
# Comp:  2             [SII]6731      0.000      0.20     204     1
# Comp:  2              HeII4687      0.000      0.20     204     1
# Comp:  2               HeI5876     0.5397      0.20     204     1
# Comp:  2          [OIII]5007_d     0.1612      0.25     204     1
# Comp:  2            [OI]6300_d      0.000      0.25     204     1
# Comp:  2           [NII]6583_d      0.000      0.26     204     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        60
#  comp.  1:        20       180
#  comp.  2:        80         1
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.34      20   180
# Comp:  1                Halpha      0.000      0.34      20   180
# Comp:  2             [SII]6716    0.02788      0.20      80     1
# Comp:  2             [SII]6731      0.000      0.20      80     1
# Comp:  2              HeII4687     0.4258      0.20      80     1
# Comp:  2               HeI5876      0.000      0.20      80     1
# Comp:  2          [OIII]5007_d     0.1668      0.25      80     1
# Comp:  2            [OI]6300_d     0.2305      0.25      80     1
# Comp:  2           [NII]6583_d     0.3291      0.25      80     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        66
#  comp.  1:      -134       344
#  comp.  2:       259         1
# chi2/DOF: 1.011; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.276      0.46    -134   344
# Comp:  1                Halpha     0.5748      0.47    -134   344
# Comp:  2             [SII]6716      0.000      0.20     259     1
# Comp:  2             [SII]6731    0.08168      0.20     259     1
# Comp:  2              HeII4687     0.8556      0.20     259     1
# Comp:  2               HeI5876      0.000      0.20     259     1
# Comp:  2          [OIII]5007_d      0.000      0.25     259     1
# Comp:  2            [OI]6300_d     0.4213      0.25     259     1
# Comp:  2           [NII]6583_d     0.2932      0.26     259     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        44
#  comp.  1:       208         1
#  comp.  2:      -523         1
# chi2/DOF: 0.9650; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 103; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1625      0.20     208     1
# Comp:  1                Halpha     0.3025      0.20     208     1
# Comp:  2             [SII]6716      0.000      0.20    -523     1
# Comp:  2             [SII]6731    0.02639      0.20    -523     1
# Comp:  2              HeII4687     0.1009      0.20    -523     1
# Comp:  2               HeI5876    0.03928      0.20    -523     1
# Comp:  2          [OIII]5007_d     0.2295      0.25    -523     1
# Comp:  2            [OI]6300_d      2.869      0.25    -523     1
# Comp:  2           [NII]6583_d      0.000      0.25    -523     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        60
#  comp.  1:       -80       308
#  comp.  2:      -109       131
# chi2/DOF: 1.016; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.612      0.44     -80   308
# Comp:  1                Halpha     0.7430      0.44     -80   308
# Comp:  2             [SII]6716     0.3022      0.30    -109   131
# Comp:  2             [SII]6731      0.000      0.30    -109   131
# Comp:  2              HeII4687     0.2592      0.30    -109   131
# Comp:  2               HeI5876      0.000      0.30    -109   131
# Comp:  2          [OIII]5007_d     0.2394      0.38    -109   131
# Comp:  2            [OI]6300_d    0.09496      0.38    -109   131
# Comp:  2           [NII]6583_d     0.1636      0.38    -109   131
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        28
#  comp.  1:      -195       273
#  comp.  2:       -40         1
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9003      0.41    -195   273
# Comp:  1                Halpha     0.7103      0.41    -195   273
# Comp:  2             [SII]6716     0.3701      0.20     -40     1
# Comp:  2             [SII]6731     0.3667      0.20     -40     1
# Comp:  2              HeII4687     0.2065      0.20     -40     1
# Comp:  2               HeI5876      0.000      0.20     -40     1
# Comp:  2          [OIII]5007_d    0.08025      0.25     -40     1
# Comp:  2            [OI]6300_d      0.000      0.25     -40     1
# Comp:  2           [NII]6583_d    0.07274      0.25     -40     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:      -154        50
#  comp.  2:         0        55
# chi2/DOF: 1.020; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3856      0.22    -154    50
# Comp:  1                Halpha      0.000      0.22    -154    50
# Comp:  2             [SII]6716     0.2743      0.23       0    55
# Comp:  2             [SII]6731      0.000      0.23       0    55
# Comp:  2              HeII4687     0.3073      0.23       0    55
# Comp:  2               HeI5876    0.04483      0.23       0    55
# Comp:  2          [OIII]5007_d     0.1286      0.29       0    55
# Comp:  2            [OI]6300_d      0.000      0.29       0    55
# Comp:  2           [NII]6583_d     0.3209      0.29       0    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        33
#  comp.  1:       -51       235
#  comp.  2:       -61        44
# chi2/DOF: 1.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.725      0.39     -51   235
# Comp:  1                Halpha     0.6132      0.39     -51   235
# Comp:  2             [SII]6716      0.000      0.22     -61    44
# Comp:  2             [SII]6731      0.000      0.22     -61    44
# Comp:  2              HeII4687     0.1357      0.22     -61    44
# Comp:  2               HeI5876     0.2781      0.22     -61    44
# Comp:  2          [OIII]5007_d    0.07133      0.28     -61    44
# Comp:  2            [OI]6300_d     0.2183      0.28     -61    44
# Comp:  2           [NII]6583_d     0.1841      0.28     -61    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        12
#  comp.  1:        96       106
#  comp.  2:        57       101
# chi2/DOF: 1.017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5422      0.28      96   106
# Comp:  1                Halpha     0.3329      0.28      96   106
# Comp:  2             [SII]6716     0.4029      0.27      57   101
# Comp:  2             [SII]6731    0.05257      0.27      57   101
# Comp:  2              HeII4687     0.4981      0.27      57   101
# Comp:  2               HeI5876      0.000      0.27      57   101
# Comp:  2          [OIII]5007_d     0.4794      0.34      57   101
# Comp:  2            [OI]6300_d      0.000      0.34      57   101
# Comp:  2           [NII]6583_d     0.6190      0.34      57   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        78
#  comp.  1:      -162       200
#  comp.  2:      -526         1
# chi2/DOF: 0.9578; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 99; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9555      0.36    -162   200
# Comp:  1                Halpha     0.4306      0.36    -162   200
# Comp:  2             [SII]6716    0.09739      0.20    -526     1
# Comp:  2             [SII]6731    0.06508      0.20    -526     1
# Comp:  2              HeII4687      0.000      0.20    -526     1
# Comp:  2               HeI5876     0.1814      0.20    -526     1
# Comp:  2          [OIII]5007_d      0.000      0.25    -526     1
# Comp:  2            [OI]6300_d      3.052      0.25    -526     1
# Comp:  2           [NII]6583_d   0.007865      0.25    -526     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:      -107       325
#  comp.  2:        76       363
# chi2/DOF: 1.017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.467      0.45    -107   325
# Comp:  1                Halpha     0.3114      0.47    -107   325
# Comp:  2             [SII]6716     0.9825      0.54      76   363
# Comp:  2             [SII]6731      0.000      0.54      76   363
# Comp:  2              HeII4687     0.4862      0.47      76   363
# Comp:  2               HeI5876     0.3189      0.47      76   363
# Comp:  2          [OIII]5007_d      0.000      0.60      76   363
# Comp:  2            [OI]6300_d     0.6171      0.60      76   363
# Comp:  2           [NII]6583_d      1.155      0.62      76   363
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        64
#  comp.  1:       262      1000
#  comp.  2:       235       230
# chi2/DOF: 1.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.78     262  1000
# Comp:  1                Halpha      1.537      0.98     262  1000
# Comp:  2             [SII]6716      1.302      0.39     235   230
# Comp:  2             [SII]6731      0.000      0.39     235   230
# Comp:  2              HeII4687     0.3470      0.38     235   230
# Comp:  2               HeI5876     0.2145      0.38     235   230
# Comp:  2          [OIII]5007_d     0.8418      0.48     235   230
# Comp:  2            [OI]6300_d     0.5857      0.48     235   230
# Comp:  2           [NII]6583_d      0.000      0.60     235   230
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        24
#  comp.  1:        93        75
#  comp.  2:       333        83
# chi2/DOF: 1.016; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5370      0.25      93    75
# Comp:  1                Halpha     0.2180      0.25      93    75
# Comp:  2             [SII]6716     0.3384      0.25     333    83
# Comp:  2             [SII]6731      0.000      0.25     333    83
# Comp:  2              HeII4687      0.000      0.25     333    83
# Comp:  2               HeI5876      0.000      0.25     333    83
# Comp:  2          [OIII]5007_d     0.8802      0.32     333    83
# Comp:  2            [OI]6300_d      0.000      0.32     333    83
# Comp:  2           [NII]6583_d     0.4936      0.32     333    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         8
#  comp.  1:       133         1
#  comp.  2:        50        68
# chi2/DOF: 1.019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1337      0.20     133     1
# Comp:  1                Halpha     0.1756      0.20     133     1
# Comp:  2             [SII]6716     0.1556      0.24      50    68
# Comp:  2             [SII]6731      0.000      0.24      50    68
# Comp:  2              HeII4687     0.4464      0.24      50    68
# Comp:  2               HeI5876    0.05902      0.24      50    68
# Comp:  2          [OIII]5007_d      0.000      0.30      50    68
# Comp:  2            [OI]6300_d      0.000      0.30      50    68
# Comp:  2           [NII]6583_d    0.05326      0.30      50    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -96       293
#  comp.  2:        49       144
# chi2/DOF: 1.017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.748      0.43     -96   293
# Comp:  1                Halpha     0.6257      0.43     -96   293
# Comp:  2             [SII]6716     0.3773      0.31      49   144
# Comp:  2             [SII]6731     0.3846      0.31      49   144
# Comp:  2              HeII4687     0.5690      0.31      49   144
# Comp:  2               HeI5876      0.000      0.31      49   144
# Comp:  2          [OIII]5007_d     0.1844      0.39      49   144
# Comp:  2            [OI]6300_d      0.000      0.39      49   144
# Comp:  2           [NII]6583_d     0.6597      0.39      49   144
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        42
#  comp.  1:      -235      1000
#  comp.  2:      -593       114
# chi2/DOF: 0.9394; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 18; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.863      0.78    -235  1000
# Comp:  1                Halpha      2.061      0.90    -235  1000
# Comp:  2             [SII]6716    0.09742      0.28    -593   114
# Comp:  2             [SII]6731     0.3689      0.28    -593   114
# Comp:  2              HeII4687     0.2618      0.28    -593   114
# Comp:  2               HeI5876   0.008971      0.28    -593   114
# Comp:  2          [OIII]5007_d      0.000      0.36    -593   114
# Comp:  2            [OI]6300_d      4.712      0.36    -593   114
# Comp:  2           [NII]6583_d      0.000      0.41    -593   114
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        26
#  comp.  1:        28       235
#  comp.  2:        78        98
# chi2/DOF: 1.015; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.134      0.39      28   235
# Comp:  1                Halpha     0.2019      0.39      28   235
# Comp:  2             [SII]6716     0.3362      0.27      78    98
# Comp:  2             [SII]6731      0.000      0.27      78    98
# Comp:  2              HeII4687     0.4401      0.27      78    98
# Comp:  2               HeI5876      0.000      0.27      78    98
# Comp:  2          [OIII]5007_d     0.2981      0.34      78    98
# Comp:  2            [OI]6300_d     0.4521      0.34      78    98
# Comp:  2           [NII]6583_d      0.000      0.34      78    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        36
#  comp.  1:       -33       345
#  comp.  2:       -89       104
# chi2/DOF: 1.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.002      0.46     -33   345
# Comp:  1                Halpha     0.2066      0.46     -33   345
# Comp:  2             [SII]6716      0.000      0.27     -89   104
# Comp:  2             [SII]6731     0.6926      0.27     -89   104
# Comp:  2              HeII4687     0.1966      0.27     -89   104
# Comp:  2               HeI5876      0.000      0.27     -89   104
# Comp:  2          [OIII]5007_d    0.06619      0.35     -89   104
# Comp:  2            [OI]6300_d   0.008668      0.35     -89   104
# Comp:  2           [NII]6583_d     0.5060      0.35     -89   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:      2020       101
#  comp.  2:       -79        82
# chi2/DOF: 1.017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3985      0.27    2020   101
# Comp:  1                Halpha    0.07038      0.27    2020   101
# Comp:  2             [SII]6716     0.6075      0.25     -79    82
# Comp:  2             [SII]6731     0.6269      0.25     -79    82
# Comp:  2              HeII4687      0.000      0.25     -79    82
# Comp:  2               HeI5876      0.000      0.25     -79    82
# Comp:  2          [OIII]5007_d      0.000      0.32     -79    82
# Comp:  2            [OI]6300_d      0.000      0.32     -79    82
# Comp:  2           [NII]6583_d     0.3842      0.32     -79    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:      -253       384
#  comp.  2:       288       183
# chi2/DOF: 1.020; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.257      0.49    -253   384
# Comp:  1                Halpha     0.1890      0.51    -253   384
# Comp:  2             [SII]6716    0.01868      0.34     288   183
# Comp:  2             [SII]6731     0.1185      0.34     288   183
# Comp:  2              HeII4687     0.1315      0.34     288   183
# Comp:  2               HeI5876      0.000      0.34     288   183
# Comp:  2          [OIII]5007_d     0.1463      0.43     288   183
# Comp:  2            [OI]6300_d      0.000      0.43     288   183
# Comp:  2           [NII]6583_d     0.9516      0.45     288   183
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:      -116       331
#  comp.  2:       -31       158
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.934      0.45    -116   331
# Comp:  1                Halpha     0.1910      0.46    -116   331
# Comp:  2             [SII]6716     0.4871      0.32     -31   158
# Comp:  2             [SII]6731     0.2073      0.32     -31   158
# Comp:  2              HeII4687     0.6554      0.32     -31   158
# Comp:  2               HeI5876      0.000      0.32     -31   158
# Comp:  2          [OIII]5007_d      0.000      0.41     -31   158
# Comp:  2            [OI]6300_d      0.000      0.41     -31   158
# Comp:  2           [NII]6583_d     0.2490      0.41     -31   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        74
#  comp.  1:      -104       126
#  comp.  2:       213       219
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6132      0.29    -104   126
# Comp:  1                Halpha     0.3906      0.30    -104   126
# Comp:  2             [SII]6716     0.7902      0.38     213   219
# Comp:  2             [SII]6731      0.000      0.38     213   219
# Comp:  2              HeII4687     0.4350      0.37     213   219
# Comp:  2               HeI5876      0.000      0.37     213   219
# Comp:  2          [OIII]5007_d    0.08110      0.47     213   219
# Comp:  2            [OI]6300_d      1.103      0.47     213   219
# Comp:  2           [NII]6583_d     0.8420      0.48     213   219
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        27
#  comp.  1:        84       209
#  comp.  2:       488       753
# chi2/DOF: 1.019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.157      0.37      84   209
# Comp:  1                Halpha     0.1130      0.39      84   209
# Comp:  2             [SII]6716     0.5218       1.2     488   753
# Comp:  2             [SII]6731      0.000       1.2     488   753
# Comp:  2              HeII4687      0.000      0.68     488   753
# Comp:  2               HeI5876      1.541      0.68     488   753
# Comp:  2          [OIII]5007_d      0.000      0.85     488   753
# Comp:  2            [OI]6300_d      0.000      0.85     488   753
# Comp:  2           [NII]6583_d     0.3410      0.84     488   753
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58       113
#  comp.  1:        20       354
#  comp.  2:       290         1
# chi2/DOF: 1.010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 82; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.729      0.47      20   354
# Comp:  1                Halpha     0.7948      0.47      20   354
# Comp:  2             [SII]6716    0.07234      0.20     290     1
# Comp:  2             [SII]6731    0.06948      0.20     290     1
# Comp:  2              HeII4687     0.9011      0.20     290     1
# Comp:  2               HeI5876      0.000      0.20     290     1
# Comp:  2          [OIII]5007_d      0.000      0.25     290     1
# Comp:  2            [OI]6300_d      0.000      0.25     290     1
# Comp:  2           [NII]6583_d     0.2715      0.26     290     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        32
#  comp.  1:      -111       319
#  comp.  2:       193       108
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.417      0.45    -111   319
# Comp:  1                Halpha     0.4087      0.45    -111   319
# Comp:  2             [SII]6716    0.01824      0.28     193   108
# Comp:  2             [SII]6731      0.000      0.28     193   108
# Comp:  2              HeII4687      1.052      0.28     193   108
# Comp:  2               HeI5876      0.000      0.28     193   108
# Comp:  2          [OIII]5007_d     0.4121      0.35     193   108
# Comp:  2            [OI]6300_d     0.1673      0.35     193   108
# Comp:  2           [NII]6583_d     0.1141      0.35     193   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        63
#  comp.  1:        74        53
#  comp.  2:       271         1
# chi2/DOF: 1.009; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 15; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5395      0.23      74    53
# Comp:  1                Halpha    0.05859      0.23      74    53
# Comp:  2             [SII]6716      0.000      0.20     271     1
# Comp:  2             [SII]6731     0.1549      0.20     271     1
# Comp:  2              HeII4687     0.8261      0.20     271     1
# Comp:  2               HeI5876      0.000      0.20     271     1
# Comp:  2          [OIII]5007_d      0.000      0.25     271     1
# Comp:  2            [OI]6300_d     0.1457      0.25     271     1
# Comp:  2           [NII]6583_d    0.06286      0.25     271     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        43
#  comp.  1:        88         1
#  comp.  2:       245         1
# chi2/DOF: 1.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1550      0.20      88     1
# Comp:  1                Halpha     0.1432      0.20      88     1
# Comp:  2             [SII]6716     0.1782      0.20     245     1
# Comp:  2             [SII]6731      0.000      0.20     245     1
# Comp:  2              HeII4687     0.7975      0.20     245     1
# Comp:  2               HeI5876     0.4932      0.20     245     1
# Comp:  2          [OIII]5007_d    0.06629      0.25     245     1
# Comp:  2            [OI]6300_d      0.000      0.25     245     1
# Comp:  2           [NII]6583_d      0.000      0.25     245     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        49
#  comp.  1:        34       183
#  comp.  2:       -16       320
# chi2/DOF: 1.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.06595      0.34      34   183
# Comp:  1                Halpha      0.000      0.35      34   183
# Comp:  2             [SII]6716     0.8777      0.48     -16   320
# Comp:  2             [SII]6731     0.5425      0.48     -16   320
# Comp:  2              HeII4687      0.000      0.45     -16   320
# Comp:  2               HeI5876      0.000      0.45     -16   320
# Comp:  2          [OIII]5007_d     0.1838      0.56     -16   320
# Comp:  2            [OI]6300_d      0.000      0.56     -16   320
# Comp:  2           [NII]6583_d      0.000      0.57     -16   320
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        69
#  comp.  1:        31       286
#  comp.  2:       -18        46
# chi2/DOF: 1.009; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5876      0.42      31   286
# Comp:  1                Halpha     0.6866      0.42      31   286
# Comp:  2             [SII]6716     0.3638      0.22     -18    46
# Comp:  2             [SII]6731     0.2162      0.22     -18    46
# Comp:  2              HeII4687     0.2481      0.22     -18    46
# Comp:  2               HeI5876     0.3418      0.22     -18    46
# Comp:  2          [OIII]5007_d    0.09979      0.28     -18    46
# Comp:  2            [OI]6300_d    0.02760      0.28     -18    46
# Comp:  2           [NII]6583_d     0.3723      0.28     -18    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        49
#  comp.  1:        40       461
#  comp.  2:       -18        23
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.211      0.53      40   461
# Comp:  1                Halpha     0.2760      0.54      40   461
# Comp:  2             [SII]6716    0.07255      0.21     -18    23
# Comp:  2             [SII]6731      0.000      0.21     -18    23
# Comp:  2              HeII4687    0.08007      0.21     -18    23
# Comp:  2               HeI5876     0.3260      0.21     -18    23
# Comp:  2          [OIII]5007_d    0.09907      0.26     -18    23
# Comp:  2            [OI]6300_d    0.03564      0.26     -18    23
# Comp:  2           [NII]6583_d     0.3025      0.26     -18    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:      -241       368
#  comp.  2:       258       361
# chi2/DOF: 1.016; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.035      0.48    -241   368
# Comp:  1                Halpha    0.07205      0.50    -241   368
# Comp:  2             [SII]6716     0.4802      0.53     258   361
# Comp:  2             [SII]6731      0.000      0.53     258   361
# Comp:  2              HeII4687     0.7287      0.47     258   361
# Comp:  2               HeI5876      1.117      0.47     258   361
# Comp:  2          [OIII]5007_d      0.000      0.60     258   361
# Comp:  2            [OI]6300_d      0.000      0.60     258   361
# Comp:  2           [NII]6583_d      0.000      0.63     258   361
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        68
#  comp.  1:       172         1
#  comp.  2:       -88       125
# chi2/DOF: 1.017; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1603      0.20     172     1
# Comp:  1                Halpha     0.2041      0.20     172     1
# Comp:  2             [SII]6716     0.3725      0.29     -88   125
# Comp:  2             [SII]6731     0.7566      0.29     -88   125
# Comp:  2              HeII4687     0.1966      0.29     -88   125
# Comp:  2               HeI5876     0.1942      0.29     -88   125
# Comp:  2          [OIII]5007_d     0.1103      0.37     -88   125
# Comp:  2            [OI]6300_d     0.3607      0.37     -88   125
# Comp:  2           [NII]6583_d     0.4289      0.37     -88   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        39
#  comp.  1:       -24        82
#  comp.  2:       215        63
# chi2/DOF: 1.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.25     -24    82
# Comp:  1                Halpha     0.1862      0.25     -24    82
# Comp:  2             [SII]6716      0.000      0.24     215    63
# Comp:  2             [SII]6731    0.07745      0.24     215    63
# Comp:  2              HeII4687      0.000      0.24     215    63
# Comp:  2               HeI5876     0.6026      0.24     215    63
# Comp:  2          [OIII]5007_d      0.000      0.30     215    63
# Comp:  2            [OI]6300_d      0.000      0.30     215    63
# Comp:  2           [NII]6583_d     0.1505      0.30     215    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        75
#  comp.  1:       234       646
#  comp.  2:        99       205
# chi2/DOF: 1.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.826      0.63     234   646
# Comp:  1                Halpha     0.5449      0.72     234   646
# Comp:  2             [SII]6716      1.277      0.36      99   205
# Comp:  2             [SII]6731     0.4007      0.36      99   205
# Comp:  2              HeII4687     0.5132      0.36      99   205
# Comp:  2               HeI5876      0.000      0.36      99   205
# Comp:  2          [OIII]5007_d     0.5941      0.46      99   205
# Comp:  2            [OI]6300_d     0.2728      0.46      99   205
# Comp:  2           [NII]6583_d    0.04575      0.52      99   205
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        38
#  comp.  1:       242       118
#  comp.  2:        41       126
# chi2/DOF: 1.019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.29     242   118
# Comp:  1                Halpha     0.1254      0.29     242   118
# Comp:  2             [SII]6716      0.000      0.29      41   126
# Comp:  2             [SII]6731     0.2215      0.29      41   126
# Comp:  2              HeII4687     0.4945      0.29      41   126
# Comp:  2               HeI5876      0.000      0.29      41   126
# Comp:  2          [OIII]5007_d     0.3191      0.37      41   126
# Comp:  2            [OI]6300_d     0.1541      0.37      41   126
# Comp:  2           [NII]6583_d     0.5942      0.37      41   126
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        24
#  comp.  1:        17       390
#  comp.  2:       -41       198
# chi2/DOF: 1.020; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.087      0.49      17   390
# Comp:  1                Halpha     0.9039      0.50      17   390
# Comp:  2             [SII]6716     0.1790      0.36     -41   198
# Comp:  2             [SII]6731     0.3802      0.36     -41   198
# Comp:  2              HeII4687    0.09264      0.36     -41   198
# Comp:  2               HeI5876      0.000      0.36     -41   198
# Comp:  2          [OIII]5007_d     0.5597      0.45     -41   198
# Comp:  2            [OI]6300_d      0.000      0.45     -41   198
# Comp:  2           [NII]6583_d     0.2308      0.46     -41   198
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        63
#  comp.  1:      -175       185
#  comp.  2:      -536         1
# chi2/DOF: 0.9665; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8640      0.35    -175   185
# Comp:  1                Halpha     0.3493      0.35    -175   185
# Comp:  2             [SII]6716    0.08404      0.20    -536     1
# Comp:  2             [SII]6731    0.02604      0.20    -536     1
# Comp:  2              HeII4687      0.000      0.20    -536     1
# Comp:  2               HeI5876      0.000      0.20    -536     1
# Comp:  2          [OIII]5007_d      0.000      0.25    -536     1
# Comp:  2            [OI]6300_d      2.853      0.25    -536     1
# Comp:  2           [NII]6583_d    0.07003      0.25    -536     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        47
#  comp.  1:       -29       363
#  comp.  2:      -524         1
# chi2/DOF: 0.9510; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 18; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.812      0.47     -29   363
# Comp:  1                Halpha     0.8911      0.49     -29   363
# Comp:  2             [SII]6716   0.006588      0.20    -524     1
# Comp:  2             [SII]6731      0.000      0.20    -524     1
# Comp:  2              HeII4687      0.000      0.20    -524     1
# Comp:  2               HeI5876     0.2429      0.20    -524     1
# Comp:  2          [OIII]5007_d      0.000      0.25    -524     1
# Comp:  2            [OI]6300_d      3.034      0.25    -524     1
# Comp:  2           [NII]6583_d    0.05335      0.26    -524     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -88       323
#  comp.  2:        55       428
# chi2/DOF: 1.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.642      0.45     -88   323
# Comp:  1                Halpha      0.000      0.47     -88   323
# Comp:  2             [SII]6716     0.8362      0.63      55   428
# Comp:  2             [SII]6731      0.000      0.63      55   428
# Comp:  2              HeII4687      0.000      0.51      55   428
# Comp:  2               HeI5876     0.5580      0.51      55   428
# Comp:  2          [OIII]5007_d     0.3280      0.65      55   428
# Comp:  2            [OI]6300_d      1.206      0.65      55   428
# Comp:  2           [NII]6583_d     0.4698      0.68      55   428
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        18
#  comp.  1:      -110       306
#  comp.  2:      -175        73
# chi2/DOF: 1.019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.879      0.44    -110   306
# Comp:  1                Halpha     0.5432      0.44    -110   306
# Comp:  2             [SII]6716     0.1253      0.25    -175    73
# Comp:  2             [SII]6731     0.4209      0.25    -175    73
# Comp:  2              HeII4687    0.05498      0.25    -175    73
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.053      0.55      39   492
# Comp:  1                Halpha      1.065      0.60      39   492
# Comp:  2             [SII]6716    0.01689      0.20    -544     1
# Comp:  2             [SII]6731     0.2823      0.20    -544     1
# Comp:  2              HeII4687      0.000      0.20    -544     1
# Comp:  2               HeI5876     0.2173      0.20    -544     1
# Comp:  2          [OIII]5007_d     0.2589      0.25    -544     1
# Comp:  2            [OI]6300_d      2.835      0.25    -544     1
# Comp:  2           [NII]6583_d      0.000      0.27    -544     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:     -1213      1000
#  comp.  2:      -520         1
# chi2/DOF: 0.9630; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 18; Func calls: 133; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.729      0.78   -1213  1000
# Comp:  1                Halpha     0.4208      0.80   -1213  1000
# Comp:  2             [SII]6716      0.000      0.20    -520     1
# Comp:  2             [SII]6731      0.000      0.20    -520     1
# Comp:  2              HeII4687      0.000      0.20    -520     1
# Comp:  2               HeI5876      0.000      0.20    -520     1
# Comp:  2          [OIII]5007_d     0.1977      0.25    -520     1
# Comp:  2            [OI]6300_d      2.864      0.25    -520     1
# Comp:  2           [NII]6583_d    0.09627      0.26    -520     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        18
#  comp.  1:       -42       322
#  comp.  2:      -115       333
# chi2/DOF: 1.010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.834      0.45     -42   322
# Comp:  1                Halpha     0.8146      0.46     -42   322
# Comp:  2             [SII]6716     0.3405      0.50    -115   333
# Comp:  2             [SII]6731      0.000      0.50    -115   333
# Comp:  2              HeII4687     0.5542      0.45    -115   333
# Comp:  2               HeI5876     0.4369      0.45    -115   333
# Comp:  2          [OIII]5007_d      1.014      0.57    -115   333
# Comp:  2            [OI]6300_d      1.899      0.57    -115   333
# Comp:  2           [NII]6583_d     0.3854      0.60    -115   333
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        35
#  comp.  1:        -4       160
#  comp.  2:      -538         1
# chi2/DOF: 0.9601; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6123      0.32      -4   160
# Comp:  1                Halpha     0.1195      0.33      -4   160
# Comp:  2             [SII]6716      0.000      0.20    -538     1
# Comp:  2             [SII]6731     0.1284      0.20    -538     1
# Comp:  2              HeII4687     0.1521      0.20    -538     1
# Comp:  2               HeI5876      0.000      0.20    -538     1
# Comp:  2          [OIII]5007_d      0.000      0.25    -538     1
# Comp:  2            [OI]6300_d      3.031      0.25    -538     1
# Comp:  2           [NII]6583_d      0.000      0.25    -538     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        41
#  comp.  1:       220       156
#  comp.  2:       177       139
# chi2/DOF: 1.019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.08680      0.32     220   156
# Comp:  1                Halpha     0.1728      0.32     220   156
# Comp:  2             [SII]6716     0.2806      0.31     177   139
# Comp:  2             [SII]6731    0.03836      0.31     177   139
# Comp:  2              HeII4687     0.5580      0.31     177   139
# Comp:  2               HeI5876      0.000      0.31     177   139
# Comp:  2          [OIII]5007_d     0.9964      0.39     177   139
# Comp:  2            [OI]6300_d      0.000      0.39     177   139
# Comp:  2           [NII]6583_d      0.000      0.39     177   139
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        62
#  comp.  1:      -789       549
#  comp.  2:       166         1
# chi2/DOF: 1.011; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.646      0.58    -789   549
# Comp:  1                Halpha      0.000      0.59    -789   549
# Comp:  2             [SII]6716   0.005977      0.20     166     1
# Comp:  2             [SII]6731      0.000      0.20     166     1
# Comp:  2              HeII4687     0.4559      0.20     166     1
# Comp:  2               HeI5876     0.5233      0.20     166     1
# Comp:  2          [OIII]5007_d      0.000      0.25     166     1
# Comp:  2            [OI]6300_d    0.05880      0.25     166     1
# Comp:  2           [NII]6583_d    0.04970      0.26     166     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:        46       432
#  comp.  2:       330       386
# chi2/DOF: 1.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.193      0.52      46   432
# Comp:  1                Halpha      0.000      0.55      46   432
# Comp:  2             [SII]6716     0.9469      0.57     330   386
# Comp:  2             [SII]6731      0.000      0.57     330   386
# Comp:  2              HeII4687      0.000      0.49     330   386
# Comp:  2               HeI5876      1.239      0.49     330   386
# Comp:  2          [OIII]5007_d      0.000      0.62     330   386
# Comp:  2            [OI]6300_d      0.000      0.62     330   386
# Comp:  2           [NII]6583_d     0.5259      0.66     330   386
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        32
#  comp.  1:        33       191
#  comp.  2:        23       149
# chi2/DOF: 1.021; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3642      0.35      33   191
# Comp:  1                Halpha     0.6876      0.35      33   191
# Comp:  2             [SII]6716     0.2628      0.32      23   149
# Comp:  2             [SII]6731      0.000      0.32      23   149
# Comp:  2              HeII4687     0.4317      0.32      23   149
# Comp:  2               HeI5876     0.2115      0.32      23   149
# Comp:  2          [OIII]5007_d     0.3047      0.40      23   149
# Comp:  2            [OI]6300_d      0.000      0.40      23   149
# Comp:  2           [NII]6583_d     0.3121      0.40      23   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        67
#  comp.  1:      -129       274
#  comp.  2:       251         1
# chi2/DOF: 1.009; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.856      0.41    -129   274
# Comp:  1                Halpha     0.7182      0.42    -129   274
# Comp:  2             [SII]6716      0.000      0.20     251     1
# Comp:  2             [SII]6731      0.000      0.20     251     1
# Comp:  2              HeII4687     0.7828      0.20     251     1
# Comp:  2               HeI5876     0.3996      0.20     251     1
# Comp:  2          [OIII]5007_d     0.6254      0.25     251     1
# Comp:  2            [OI]6300_d     0.2888      0.25     251     1
# Comp:  2           [NII]6583_d     0.1240      0.26     251     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        18
#  comp.  1:        30       276
#  comp.  2:       220        92
# chi2/DOF: 1.011; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.42      30   276
# Comp:  1                Halpha     0.7828      0.42      30   276
# Comp:  2             [SII]6716     0.5657      0.26     220    92
# Comp:  2             [SII]6731    0.07831      0.26     220    92
# Comp:  2              HeII4687      0.000      0.26     220    92
# Comp:  2               HeI5876    0.05118      0.26     220    92
# Comp:  2          [OIII]5007_d     0.8275      0.33     220    92
# Comp:  2            [OI]6300_d     0.4754      0.33     220    92
# Comp:  2           [NII]6583_d     0.3538      0.33     220    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       187       500
#  comp.  2:       275         1
# chi2/DOF: 1.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7041      0.55     187   500
# Comp:  1                Halpha     0.3029      0.56     187   500
# Comp:  2             [SII]6716      0.000      0.20     275     1
# Comp:  2             [SII]6731      0.000      0.20     275     1
# Comp:  2              HeII4687     0.8593      0.20     275     1
# Comp:  2               HeI5876      0.000      0.20     275     1
# Comp:  2          [OIII]5007_d      0.000      0.25     275     1
# Comp:  2            [OI]6300_d      0.000      0.25     275     1
# Comp:  2           [NII]6583_d     0.2652      0.26     275     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        49
#  comp.  1:       -71       333
#  comp.  2:       196         1
# chi2/DOF: 1.010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.476      0.46     -71   333
# Comp:  1                Halpha     0.8339      0.46     -71   333
# Comp:  2             [SII]6716      0.000      0.20     196     1
# Comp:  2             [SII]6731      0.000      0.20     196     1
# Comp:  2              HeII4687      0.000      0.20     196     1
# Comp:  2               HeI5876     0.5603      0.20     196     1
# Comp:  2          [OIII]5007_d     0.5460      0.25     196     1
# Comp:  2            [OI]6300_d     0.1206      0.25     196     1
# Comp:  2           [NII]6583_d      0.000      0.25     196     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        28
#  comp.  1:       157       248
#  comp.  2:       -36       245
# chi2/DOF: 1.020; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.40     157   248
# Comp:  1                Halpha     0.9834      0.40     157   248
# Comp:  2             [SII]6716     0.4931      0.40     -36   245
# Comp:  2             [SII]6731      0.000      0.40     -36   245
# Comp:  2              HeII4687     0.6132      0.39     -36   245
# Comp:  2               HeI5876    0.03862      0.39     -36   245
# Comp:  2          [OIII]5007_d     0.3006      0.50     -36   245
# Comp:  2            [OI]6300_d     0.2806      0.50     -36   245
# Comp:  2           [NII]6583_d     0.2282      0.50     -36   245
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -23       272
#  comp.  2:       122        98
# chi2/DOF: 1.018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.183      0.41     -23   272
# Comp:  1                Halpha     0.2968      0.41     -23   272
# Comp:  2             [SII]6716     0.4949      0.27     122    98
# Comp:  2             [SII]6731      0.000      0.27     122    98
# Comp:  2              HeII4687      0.000      0.27     122    98
# Comp:  2               HeI5876     0.3537      0.27     122    98
# Comp:  2          [OIII]5007_d     0.4180      0.34     122    98
# Comp:  2            [OI]6300_d     0.1899      0.34     122    98
# Comp:  2           [NII]6583_d      0.000      0.34     122    98
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.28994219, 0.58994231, 0.44850486, 0.26534365, 0.38884175,
#        0.34490241, 0.37227931, 1.06687051, 0.37766648])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_15580\2709300755.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.        , 0.        , 0.54293027, 0.        , 0.21136624,
#        0.        , 0.33365768, 0.08256103, 0.44280105])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.000000    0.087219
# 1        Halpha  0.000000    0.039889
# 2     [SII]6716  0.036710    0.030326
# 3     [SII]6731  0.000000    0.017941
# 4      HeII4687  0.014291    0.026291
# 5       HeI5876  0.000000    0.023320
# 6  [OIII]5007_d  0.022560    0.025172
# 7    [OI]6300_d  0.005582    0.072136
# 8   [NII]6583_d  0.029940    0.025536
#           Name      Flux  Error_flux
# 0        Hbeta  0.000000    0.087219
# 1       Halpha  0.000000    0.039889
# 2    [SII]6716  0.036710    0.030326
# 3    [SII]6731  0.000000    0.017941
# 4     HeII4687  0.014291    0.026291
# 5      HeI5876  0.000000    0.023320
# 6   [OIII]4959  0.005640    0.025172
# 7   [OIII]5007  0.016920    0.025172
# 8     [OI]6300  0.004187    0.072136
# 9     [OI]6364  0.001396    0.072136
# 10   [NII]6548  0.007485    0.025536
# 11   [NII]6583  0.022455    0.025536

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06761472098145613
