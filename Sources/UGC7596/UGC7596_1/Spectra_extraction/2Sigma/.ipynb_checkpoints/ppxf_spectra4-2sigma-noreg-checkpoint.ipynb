# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2221834  2.22292218 2.22366096 ... 3.5409075  3.54164628 3.54238506]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
# chi2/DOF: 0.03813; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
# chi2/DOF: 0.02353; DOF: 1918; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [1.59811118 1.44628396 1.22423562 ... 0.9308221  0.86885828 0.75318239]
# [1.45759682 1.47378035 1.48440978 ... 0.75879383 0.75651826 0.74686721]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-30.45218119,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:        -8        17
#  comp.  2:       -13        17
# chi2/DOF: 1.150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.28      0.37      -8    17
# Comp:  1                Halpha      43.82      0.37      -8    17
# Comp:  2             [SII]6716      10.32      0.36     -13    17
# Comp:  2             [SII]6731      7.181      0.36     -13    17
# Comp:  2              HeII4687     0.9610      0.36     -13    17
# Comp:  2               HeI5876      0.000      0.36     -13    17
# Comp:  2          [OIII]5007_d      5.925      0.46     -13    17
# Comp:  2            [OI]6300_d     0.5397      0.46     -13    17
# Comp:  2           [NII]6583_d      7.551      0.46     -13    17
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:   33.2; gas flux:     14 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  102.2; gas flux:     60 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  23.77; gas flux:     14 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  16.79; gas flux:     10 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.114; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   9.65; gas flux:      6 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.9418; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  13.25; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:        -8        20
#  comp.  2:       -10        14
# chi2/DOF: 1.142; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.12      0.37      -8    20
# Comp:  1                Halpha      43.77      0.37      -8    20
# Comp:  2             [SII]6716      10.30      0.36     -10    14
# Comp:  2             [SII]6731      6.854      0.36     -10    14
# Comp:  2              HeII4687     0.7615      0.36     -10    14
# Comp:  2               HeI5876      0.000      0.36     -10    14
# Comp:  2          [OIII]5007_d      5.891      0.46     -10    14
# Comp:  2            [OI]6300_d     0.7705      0.46     -10    14
# Comp:  2           [NII]6583_d      7.369      0.46     -10    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -12        24
#  comp.  2:       -11        17
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.90      0.37     -12    24
# Comp:  1                Halpha      45.15      0.37     -12    24
# Comp:  2             [SII]6716      10.59      0.37     -11    17
# Comp:  2             [SII]6731      6.987      0.37     -11    17
# Comp:  2              HeII4687     0.9399      0.37     -11    17
# Comp:  2               HeI5876     0.1608      0.37     -11    17
# Comp:  2          [OIII]5007_d      5.654      0.46     -11    17
# Comp:  2            [OI]6300_d     0.5099      0.46     -11    17
# Comp:  2           [NII]6583_d      7.656      0.46     -11    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        22
#  comp.  1:        -7        10
#  comp.  2:       -11        17
# chi2/DOF: 1.137; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.95      0.36      -7    10
# Comp:  1                Halpha      44.23      0.36      -7    10
# Comp:  2             [SII]6716      10.57      0.37     -11    17
# Comp:  2             [SII]6731      7.418      0.37     -11    17
# Comp:  2              HeII4687      1.152      0.37     -11    17
# Comp:  2               HeI5876     0.1397      0.37     -11    17
# Comp:  2          [OIII]5007_d      5.481      0.46     -11    17
# Comp:  2            [OI]6300_d     0.3795      0.46     -11    17
# Comp:  2           [NII]6583_d      7.649      0.46     -11    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -11        27
#  comp.  2:       -14        26
# chi2/DOF: 1.125; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.51      0.37     -11    27
# Comp:  1                Halpha      45.52      0.37     -11    27
# Comp:  2             [SII]6716      10.30      0.37     -14    26
# Comp:  2             [SII]6731      7.338      0.37     -14    26
# Comp:  2              HeII4687      1.319      0.37     -14    26
# Comp:  2               HeI5876     0.2108      0.37     -14    26
# Comp:  2          [OIII]5007_d      6.286      0.47     -14    26
# Comp:  2            [OI]6300_d     0.4092      0.47     -14    26
# Comp:  2           [NII]6583_d      8.162      0.47     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -12        25
#  comp.  2:       -14         1
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.35      0.37     -12    25
# Comp:  1                Halpha      45.55      0.37     -12    25
# Comp:  2             [SII]6716      10.10      0.36     -14     1
# Comp:  2             [SII]6731      7.279      0.36     -14     1
# Comp:  2              HeII4687     0.9801      0.36     -14     1
# Comp:  2               HeI5876     0.3208      0.36     -14     1
# Comp:  2          [OIII]5007_d      5.152      0.45     -14     1
# Comp:  2            [OI]6300_d     0.8556      0.45     -14     1
# Comp:  2           [NII]6583_d      7.551      0.45     -14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -10        27
#  comp.  2:       -16         7
# chi2/DOF: 1.125; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.25      0.37     -10    27
# Comp:  1                Halpha      46.18      0.37     -10    27
# Comp:  2             [SII]6716      9.928      0.36     -16     7
# Comp:  2             [SII]6731      7.136      0.36     -16     7
# Comp:  2              HeII4687     0.6330      0.36     -16     7
# Comp:  2               HeI5876      0.000      0.36     -16     7
# Comp:  2          [OIII]5007_d      5.741      0.46     -16     7
# Comp:  2            [OI]6300_d     0.8556      0.46     -16     7
# Comp:  2           [NII]6583_d      7.388      0.46     -16     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        53
#  comp.  1:        -8        14
#  comp.  2:       -13        28
# chi2/DOF: 1.140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.48      0.36      -8    14
# Comp:  1                Halpha      44.28      0.36      -8    14
# Comp:  2             [SII]6716      11.05      0.37     -13    28
# Comp:  2             [SII]6731      7.089      0.37     -13    28
# Comp:  2              HeII4687      1.281      0.37     -13    28
# Comp:  2               HeI5876    0.08894      0.37     -13    28
# Comp:  2          [OIII]5007_d      6.579      0.47     -13    28
# Comp:  2            [OI]6300_d     0.8289      0.47     -13    28
# Comp:  2           [NII]6583_d      7.743      0.47     -13    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22        28
#  comp.  1:        -9        24
#  comp.  2:       -16        20
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.09      0.37      -9    24
# Comp:  1                Halpha      43.72      0.37      -9    24
# Comp:  2             [SII]6716      10.30      0.37     -16    20
# Comp:  2             [SII]6731      7.433      0.37     -16    20
# Comp:  2              HeII4687      1.123      0.37     -16    20
# Comp:  2               HeI5876      0.000      0.37     -16    20
# Comp:  2          [OIII]5007_d      5.748      0.46     -16    20
# Comp:  2            [OI]6300_d     0.7142      0.46     -16    20
# Comp:  2           [NII]6583_d      7.863      0.46     -16    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        79
#  comp.  1:       -11        23
#  comp.  2:       -11        13
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.16      0.37     -11    23
# Comp:  1                Halpha      45.50      0.37     -11    23
# Comp:  2             [SII]6716      10.53      0.36     -11    13
# Comp:  2             [SII]6731      7.141      0.36     -11    13
# Comp:  2              HeII4687     0.9576      0.36     -11    13
# Comp:  2               HeI5876      0.000      0.36     -11    13
# Comp:  2          [OIII]5007_d      5.199      0.46     -11    13
# Comp:  2            [OI]6300_d     0.2026      0.46     -11    13
# Comp:  2           [NII]6583_d      7.438      0.46     -11    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        28
#  comp.  1:        -8        10
#  comp.  2:       -14        26
# chi2/DOF: 1.130; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.19      0.36      -8    10
# Comp:  1                Halpha      44.50      0.36      -8    10
# Comp:  2             [SII]6716      10.92      0.37     -14    26
# Comp:  2             [SII]6731      6.928      0.37     -14    26
# Comp:  2              HeII4687     0.7977      0.37     -14    26
# Comp:  2               HeI5876     0.1430      0.37     -14    26
# Comp:  2          [OIII]5007_d      6.162      0.47     -14    26
# Comp:  2            [OI]6300_d      1.031      0.47     -14    26
# Comp:  2           [NII]6583_d      7.623      0.47     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:        -8        26
#  comp.  2:       -13        23
# chi2/DOF: 1.136; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.91      0.37      -8    26
# Comp:  1                Halpha      44.00      0.37      -8    26
# Comp:  2             [SII]6716      10.33      0.37     -13    23
# Comp:  2             [SII]6731      6.910      0.37     -13    23
# Comp:  2              HeII4687      1.281      0.37     -13    23
# Comp:  2               HeI5876    0.01060      0.37     -13    23
# Comp:  2          [OIII]5007_d      6.243      0.47     -13    23
# Comp:  2            [OI]6300_d     0.4593      0.47     -13    23
# Comp:  2           [NII]6583_d      7.947      0.47     -13    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        31
#  comp.  1:        -5         7
#  comp.  2:       -10        12
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.06      0.36      -5     7
# Comp:  1                Halpha      42.20      0.36      -5     7
# Comp:  2             [SII]6716      10.31      0.36     -10    12
# Comp:  2             [SII]6731      7.361      0.36     -10    12
# Comp:  2              HeII4687     0.7623      0.36     -10    12
# Comp:  2               HeI5876    0.02113      0.36     -10    12
# Comp:  2          [OIII]5007_d      5.649      0.46     -10    12
# Comp:  2            [OI]6300_d     0.4973      0.46     -10    12
# Comp:  2           [NII]6583_d      7.164      0.46     -10    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        52
#  comp.  1:        -8         7
#  comp.  2:       -14        23
# chi2/DOF: 1.135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.38      0.36      -8     7
# Comp:  1                Halpha      44.36      0.36      -8     7
# Comp:  2             [SII]6716      10.80      0.37     -14    23
# Comp:  2             [SII]6731      6.944      0.37     -14    23
# Comp:  2              HeII4687     0.8353      0.37     -14    23
# Comp:  2               HeI5876      0.000      0.37     -14    23
# Comp:  2          [OIII]5007_d      5.461      0.47     -14    23
# Comp:  2            [OI]6300_d     0.6209      0.47     -14    23
# Comp:  2           [NII]6583_d      7.725      0.47     -14    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35         1
#  comp.  1:       -12        25
#  comp.  2:       -12        16
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.27      0.37     -12    25
# Comp:  1                Halpha      45.55      0.37     -12    25
# Comp:  2             [SII]6716      10.08      0.36     -12    16
# Comp:  2             [SII]6731      7.215      0.36     -12    16
# Comp:  2              HeII4687      1.251      0.36     -12    16
# Comp:  2               HeI5876      0.000      0.36     -12    16
# Comp:  2          [OIII]5007_d      5.971      0.46     -12    16
# Comp:  2            [OI]6300_d     0.6567      0.46     -12    16
# Comp:  2           [NII]6583_d      7.427      0.46     -12    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        67
#  comp.  1:       -11        23
#  comp.  2:       -17        17
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.63      0.37     -11    23
# Comp:  1                Halpha      45.40      0.37     -11    23
# Comp:  2             [SII]6716      10.39      0.36     -17    17
# Comp:  2             [SII]6731      6.833      0.36     -17    17
# Comp:  2              HeII4687      1.255      0.36     -17    17
# Comp:  2               HeI5876    0.03864      0.36     -17    17
# Comp:  2          [OIII]5007_d      5.544      0.46     -17    17
# Comp:  2            [OI]6300_d     0.2504      0.46     -17    17
# Comp:  2           [NII]6583_d      7.786      0.46     -17    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        -9         7
#  comp.  2:       -13         1
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.55      0.36      -9     7
# Comp:  1                Halpha      43.51      0.36      -9     7
# Comp:  2             [SII]6716      10.31      0.36     -13     1
# Comp:  2             [SII]6731      7.370      0.36     -13     1
# Comp:  2              HeII4687      1.001      0.36     -13     1
# Comp:  2               HeI5876     0.1608      0.36     -13     1
# Comp:  2          [OIII]5007_d      5.355      0.45     -13     1
# Comp:  2            [OI]6300_d     0.4062      0.45     -13     1
# Comp:  2           [NII]6583_d      7.227      0.45     -13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        39
#  comp.  1:       -11        28
#  comp.  2:       -14        25
# chi2/DOF: 1.127; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.99      0.37     -11    28
# Comp:  1                Halpha      45.71      0.37     -11    28
# Comp:  2             [SII]6716      10.60      0.37     -14    25
# Comp:  2             [SII]6731      7.638      0.37     -14    25
# Comp:  2              HeII4687     0.7842      0.37     -14    25
# Comp:  2               HeI5876      0.000      0.37     -14    25
# Comp:  2          [OIII]5007_d      5.843      0.47     -14    25
# Comp:  2            [OI]6300_d      1.032      0.47     -14    25
# Comp:  2           [NII]6583_d      7.702      0.47     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        71
#  comp.  1:        -8        17
#  comp.  2:        -8         6
# chi2/DOF: 1.132; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.37      0.37      -8    17
# Comp:  1                Halpha      43.98      0.37      -8    17
# Comp:  2             [SII]6716      10.17      0.36      -8     6
# Comp:  2             [SII]6731      7.103      0.36      -8     6
# Comp:  2              HeII4687     0.9457      0.36      -8     6
# Comp:  2               HeI5876      0.000      0.36      -8     6
# Comp:  2          [OIII]5007_d      5.408      0.45      -8     6
# Comp:  2            [OI]6300_d     0.3774      0.45      -8     6
# Comp:  2           [NII]6583_d      7.637      0.45      -8     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25         1
#  comp.  1:        -9         2
#  comp.  2:       -10        19
# chi2/DOF: 1.136; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.40      0.36      -9     2
# Comp:  1                Halpha      43.87      0.36      -9     2
# Comp:  2             [SII]6716      10.37      0.37     -10    19
# Comp:  2             [SII]6731      6.841      0.37     -10    19
# Comp:  2              HeII4687      1.082      0.37     -10    19
# Comp:  2               HeI5876     0.1256      0.37     -10    19
# Comp:  2          [OIII]5007_d      6.408      0.46     -10    19
# Comp:  2            [OI]6300_d     0.1757      0.46     -10    19
# Comp:  2           [NII]6583_d      7.485      0.46     -10    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:       -10        29
#  comp.  2:       -14        18
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.34      0.38     -10    29
# Comp:  1                Halpha      45.58      0.38     -10    29
# Comp:  2             [SII]6716      10.45      0.37     -14    18
# Comp:  2             [SII]6731      7.253      0.37     -14    18
# Comp:  2              HeII4687     0.9356      0.37     -14    18
# Comp:  2               HeI5876   0.008318      0.37     -14    18
# Comp:  2          [OIII]5007_d      6.126      0.46     -14    18
# Comp:  2            [OI]6300_d     0.8003      0.46     -14    18
# Comp:  2           [NII]6583_d      7.747      0.46     -14    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:        -7        11
#  comp.  2:       -10        11
# chi2/DOF: 1.138; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.65      0.36      -7    11
# Comp:  1                Halpha      44.33      0.36      -7    11
# Comp:  2             [SII]6716      10.29      0.36     -10    11
# Comp:  2             [SII]6731      6.730      0.36     -10    11
# Comp:  2              HeII4687      1.094      0.36     -10    11
# Comp:  2               HeI5876     0.2217      0.36     -10    11
# Comp:  2          [OIII]5007_d      6.321      0.46     -10    11
# Comp:  2            [OI]6300_d     0.8344      0.46     -10    11
# Comp:  2           [NII]6583_d      7.163      0.46     -10    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68         5
#  comp.  1:       -11        26
#  comp.  2:       -13        16
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.27      0.37     -11    26
# Comp:  1                Halpha      45.49      0.37     -11    26
# Comp:  2             [SII]6716      10.31      0.36     -13    16
# Comp:  2             [SII]6731      7.365      0.36     -13    16
# Comp:  2              HeII4687      1.064      0.36     -13    16
# Comp:  2               HeI5876     0.2408      0.36     -13    16
# Comp:  2          [OIII]5007_d      6.145      0.46     -13    16
# Comp:  2            [OI]6300_d     0.9386      0.46     -13    16
# Comp:  2           [NII]6583_d      7.413      0.46     -13    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:        -8         6
#  comp.  2:       -14        25
# chi2/DOF: 1.137; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.54      0.36      -8     6
# Comp:  1                Halpha      43.80      0.36      -8     6
# Comp:  2             [SII]6716      10.92      0.37     -14    25
# Comp:  2             [SII]6731      6.957      0.37     -14    25
# Comp:  2              HeII4687      1.031      0.37     -14    25
# Comp:  2               HeI5876      0.000      0.37     -14    25
# Comp:  2          [OIII]5007_d      6.504      0.47     -14    25
# Comp:  2            [OI]6300_d     0.2364      0.47     -14    25
# Comp:  2           [NII]6583_d      7.489      0.47     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        14
#  comp.  1:        -5        12
#  comp.  2:       -14        24
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.19      0.36      -5    12
# Comp:  1                Halpha      42.51      0.36      -5    12
# Comp:  2             [SII]6716      10.82      0.37     -14    24
# Comp:  2             [SII]6731      7.558      0.37     -14    24
# Comp:  2              HeII4687      1.128      0.37     -14    24
# Comp:  2               HeI5876     0.1447      0.37     -14    24
# Comp:  2          [OIII]5007_d      6.161      0.47     -14    24
# Comp:  2            [OI]6300_d     0.2396      0.47     -14    24
# Comp:  2           [NII]6583_d      7.763      0.47     -14    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        57
#  comp.  1:       -11        25
#  comp.  2:       -17        16
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.89      0.37     -11    25
# Comp:  1                Halpha      45.04      0.37     -11    25
# Comp:  2             [SII]6716      10.08      0.36     -17    16
# Comp:  2             [SII]6731      7.161      0.36     -17    16
# Comp:  2              HeII4687      1.151      0.36     -17    16
# Comp:  2               HeI5876     0.1703      0.36     -17    16
# Comp:  2          [OIII]5007_d      5.605      0.46     -17    16
# Comp:  2            [OI]6300_d     0.2523      0.46     -17    16
# Comp:  2           [NII]6583_d      7.497      0.46     -17    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       170       348
#  comp.  1:        -6         1
#  comp.  2:       -12         1
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.90      0.36      -6     1
# Comp:  1                Halpha      42.39      0.36      -6     1
# Comp:  2             [SII]6716      10.08      0.36     -12     1
# Comp:  2             [SII]6731      7.099      0.36     -12     1
# Comp:  2              HeII4687     0.8671      0.36     -12     1
# Comp:  2               HeI5876     0.1055      0.36     -12     1
# Comp:  2          [OIII]5007_d      5.160      0.45     -12     1
# Comp:  2            [OI]6300_d     0.9801      0.45     -12     1
# Comp:  2           [NII]6583_d      7.283      0.45     -12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:        -6         2
#  comp.  2:       -11         1
# chi2/DOF: 1.133; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.33      0.36      -6     2
# Comp:  1                Halpha      42.73      0.36      -6     2
# Comp:  2             [SII]6716      10.31      0.36     -11     1
# Comp:  2             [SII]6731      6.743      0.36     -11     1
# Comp:  2              HeII4687      1.099      0.36     -11     1
# Comp:  2               HeI5876      0.000      0.36     -11     1
# Comp:  2          [OIII]5007_d      5.416      0.45     -11     1
# Comp:  2            [OI]6300_d     0.9696      0.45     -11     1
# Comp:  2           [NII]6583_d      7.309      0.45     -11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        43
#  comp.  1:       -11        26
#  comp.  2:       -13         1
# chi2/DOF: 1.127; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.76      0.37     -11    26
# Comp:  1                Halpha      45.91      0.37     -11    26
# Comp:  2             [SII]6716      10.26      0.36     -13     1
# Comp:  2             [SII]6731      7.293      0.36     -13     1
# Comp:  2              HeII4687     0.5964      0.36     -13     1
# Comp:  2               HeI5876      0.000      0.36     -13     1
# Comp:  2          [OIII]5007_d      5.935      0.45     -13     1
# Comp:  2            [OI]6300_d     0.6168      0.45     -13     1
# Comp:  2           [NII]6583_d      7.722      0.45     -13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:       -11        25
#  comp.  2:       -13        25
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.27      0.37     -11    25
# Comp:  1                Halpha      45.94      0.37     -11    25
# Comp:  2             [SII]6716      10.10      0.37     -13    25
# Comp:  2             [SII]6731      7.640      0.37     -13    25
# Comp:  2              HeII4687     0.7766      0.37     -13    25
# Comp:  2               HeI5876     0.1224      0.37     -13    25
# Comp:  2          [OIII]5007_d      6.920      0.47     -13    25
# Comp:  2            [OI]6300_d     0.2698      0.47     -13    25
# Comp:  2           [NII]6583_d      7.660      0.47     -13    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12       356
#  comp.  1:       -12        27
#  comp.  2:       -16         5
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.23      0.37     -12    27
# Comp:  1                Halpha      45.38      0.37     -12    27
# Comp:  2             [SII]6716      10.10      0.36     -16     5
# Comp:  2             [SII]6731      7.098      0.36     -16     5
# Comp:  2              HeII4687     0.9566      0.36     -16     5
# Comp:  2               HeI5876     0.1492      0.36     -16     5
# Comp:  2          [OIII]5007_d      5.433      0.45     -16     5
# Comp:  2            [OI]6300_d     0.2872      0.45     -16     5
# Comp:  2           [NII]6583_d      7.567      0.45     -16     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        83        63
#  comp.  1:        -9        26
#  comp.  2:       -13         1
# chi2/DOF: 1.130; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.86      0.37      -9    26
# Comp:  1                Halpha      43.99      0.37      -9    26
# Comp:  2             [SII]6716      9.769      0.36     -13     1
# Comp:  2             [SII]6731      7.362      0.36     -13     1
# Comp:  2              HeII4687     0.8360      0.36     -13     1
# Comp:  2               HeI5876     0.1453      0.36     -13     1
# Comp:  2          [OIII]5007_d      5.297      0.45     -13     1
# Comp:  2            [OI]6300_d     0.1358      0.45     -13     1
# Comp:  2           [NII]6583_d      7.390      0.45     -13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        62
#  comp.  1:        -8        24
#  comp.  2:       -14        26
# chi2/DOF: 1.139; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.14      0.37      -8    24
# Comp:  1                Halpha      43.68      0.37      -8    24
# Comp:  2             [SII]6716      10.33      0.37     -14    26
# Comp:  2             [SII]6731      7.376      0.37     -14    26
# Comp:  2              HeII4687      1.056      0.37     -14    26
# Comp:  2               HeI5876      0.000      0.37     -14    26
# Comp:  2          [OIII]5007_d      6.212      0.47     -14    26
# Comp:  2            [OI]6300_d     0.1772      0.47     -14    26
# Comp:  2           [NII]6583_d      7.215      0.47     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        95
#  comp.  1:       -10        27
#  comp.  2:       -11        26
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.85      0.37     -10    27
# Comp:  1                Halpha      45.61      0.37     -10    27
# Comp:  2             [SII]6716      10.73      0.37     -11    26
# Comp:  2             [SII]6731      7.453      0.37     -11    26
# Comp:  2              HeII4687     0.8675      0.37     -11    26
# Comp:  2               HeI5876      0.000      0.37     -11    26
# Comp:  2          [OIII]5007_d      5.936      0.47     -11    26
# Comp:  2            [OI]6300_d     0.6138      0.47     -11    26
# Comp:  2           [NII]6583_d      8.093      0.47     -11    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54       122
#  comp.  1:        -8        20
#  comp.  2:       -13        34
# chi2/DOF: 1.137; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.56      0.37      -8    20
# Comp:  1                Halpha      44.03      0.37      -8    20
# Comp:  2             [SII]6716      10.98      0.38     -13    34
# Comp:  2             [SII]6731      7.590      0.38     -13    34
# Comp:  2              HeII4687      1.063      0.38     -13    34
# Comp:  2               HeI5876      0.000      0.38     -13    34
# Comp:  2          [OIII]5007_d      5.928      0.48     -13    34
# Comp:  2            [OI]6300_d     0.9668      0.48     -13    34
# Comp:  2           [NII]6583_d      8.506      0.48     -13    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        76
#  comp.  1:        -5         1
#  comp.  2:       -13        20
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74      0.36      -5     1
# Comp:  1                Halpha      43.11      0.36      -5     1
# Comp:  2             [SII]6716      10.45      0.37     -13    20
# Comp:  2             [SII]6731      6.875      0.37     -13    20
# Comp:  2              HeII4687     0.6651      0.37     -13    20
# Comp:  2               HeI5876      0.000      0.37     -13    20
# Comp:  2          [OIII]5007_d      5.813      0.46     -13    20
# Comp:  2            [OI]6300_d     0.7818      0.46     -13    20
# Comp:  2           [NII]6583_d      7.662      0.46     -13    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        20
#  comp.  1:        -6         1
#  comp.  2:        -9        21
# chi2/DOF: 1.119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.01      0.36      -6     1
# Comp:  1                Halpha      42.38      0.36      -6     1
# Comp:  2             [SII]6716      10.45      0.37      -9    21
# Comp:  2             [SII]6731      7.584      0.37      -9    21
# Comp:  2              HeII4687     0.7486      0.37      -9    21
# Comp:  2               HeI5876    0.06342      0.37      -9    21
# Comp:  2          [OIII]5007_d      5.592      0.46      -9    21
# Comp:  2            [OI]6300_d     0.5236      0.46      -9    21
# Comp:  2           [NII]6583_d      7.829      0.46      -9    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        66
#  comp.  1:        -6         1
#  comp.  2:       -11        21
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.56      0.36      -6     1
# Comp:  1                Halpha      42.81      0.36      -6     1
# Comp:  2             [SII]6716      10.52      0.37     -11    21
# Comp:  2             [SII]6731      7.645      0.37     -11    21
# Comp:  2              HeII4687     0.7993      0.37     -11    21
# Comp:  2               HeI5876     0.1538      0.37     -11    21
# Comp:  2          [OIII]5007_d      5.943      0.46     -11    21
# Comp:  2            [OI]6300_d     0.8429      0.46     -11    21
# Comp:  2           [NII]6583_d      7.555      0.46     -11    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6         1
#  comp.  1:        -5         6
#  comp.  2:       -13        23
# chi2/DOF: 1.129; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.05      0.36      -5     6
# Comp:  1                Halpha      42.62      0.36      -5     6
# Comp:  2             [SII]6716      10.53      0.37     -13    23
# Comp:  2             [SII]6731      7.351      0.37     -13    23
# Comp:  2              HeII4687      1.026      0.37     -13    23
# Comp:  2               HeI5876      0.000      0.37     -13    23
# Comp:  2          [OIII]5007_d      5.496      0.47     -13    23
# Comp:  2            [OI]6300_d     0.4481      0.47     -13    23
# Comp:  2           [NII]6583_d      7.295      0.47     -13    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:        -6         1
#  comp.  2:       -13        17
# chi2/DOF: 1.126; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.96      0.36      -6     1
# Comp:  1                Halpha      42.24      0.36      -6     1
# Comp:  2             [SII]6716      10.44      0.37     -13    17
# Comp:  2             [SII]6731      7.140      0.37     -13    17
# Comp:  2              HeII4687     0.7727      0.37     -13    17
# Comp:  2               HeI5876      0.000      0.37     -13    17
# Comp:  2          [OIII]5007_d      6.215      0.46     -13    17
# Comp:  2            [OI]6300_d     0.6932      0.46     -13    17
# Comp:  2           [NII]6583_d      7.849      0.46     -13    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61         7
#  comp.  1:        -8        18
#  comp.  2:       -15        24
# chi2/DOF: 1.143; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.22      0.37      -8    18
# Comp:  1                Halpha      44.13      0.37      -8    18
# Comp:  2             [SII]6716      10.25      0.37     -15    24
# Comp:  2             [SII]6731      7.658      0.37     -15    24
# Comp:  2              HeII4687     0.9885      0.37     -15    24
# Comp:  2               HeI5876      0.000      0.37     -15    24
# Comp:  2          [OIII]5007_d      5.710      0.47     -15    24
# Comp:  2            [OI]6300_d     0.4022      0.47     -15    24
# Comp:  2           [NII]6583_d      7.437      0.47     -15    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        24
#  comp.  1:        -7        11
#  comp.  2:       -13        16
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.05      0.36      -7    11
# Comp:  1                Halpha      44.28      0.36      -7    11
# Comp:  2             [SII]6716      10.49      0.36     -13    16
# Comp:  2             [SII]6731      7.589      0.36     -13    16
# Comp:  2              HeII4687     0.9567      0.36     -13    16
# Comp:  2               HeI5876     0.2671      0.36     -13    16
# Comp:  2          [OIII]5007_d      5.460      0.46     -13    16
# Comp:  2            [OI]6300_d    0.09912      0.46     -13    16
# Comp:  2           [NII]6583_d      7.483      0.46     -13    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:        -8        25
#  comp.  2:       -11        17
# chi2/DOF: 1.136; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.67      0.37      -8    25
# Comp:  1                Halpha      44.61      0.37      -8    25
# Comp:  2             [SII]6716      10.42      0.37     -11    17
# Comp:  2             [SII]6731      6.891      0.37     -11    17
# Comp:  2              HeII4687     0.9029      0.37     -11    17
# ...
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.46      0.36      -9     4
# Comp:  1                Halpha      43.15      0.36      -9     4
# Comp:  2             [SII]6716      10.36      0.36     -15    15
# Comp:  2             [SII]6731      7.143      0.36     -15    15
# Comp:  2              HeII4687      1.012      0.36     -15    15
# Comp:  2               HeI5876     0.1626      0.36     -15    15
# Comp:  2          [OIII]5007_d      6.141      0.46     -15    15
# Comp:  2            [OI]6300_d     0.2779      0.46     -15    15
# Comp:  2           [NII]6583_d      7.531      0.46     -15    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        46
#  comp.  1:        -9         8
#  comp.  2:       -11         6
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.64      0.36      -9     8
# Comp:  1                Halpha      44.07      0.36      -9     8
# Comp:  2             [SII]6716      10.08      0.36     -11     6
# Comp:  2             [SII]6731      7.110      0.36     -11     6
# Comp:  2              HeII4687      1.025      0.36     -11     6
# Comp:  2               HeI5876     0.1835      0.36     -11     6
# Comp:  2          [OIII]5007_d      5.920      0.45     -11     6
# Comp:  2            [OI]6300_d     0.6636      0.45     -11     6
# Comp:  2           [NII]6583_d      7.381      0.45     -11     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       113         1
#  comp.  1:        -6         1
#  comp.  2:       -13        16
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.56      0.36      -6     1
# Comp:  1                Halpha      41.70      0.36      -6     1
# Comp:  2             [SII]6716      10.63      0.36     -13    16
# Comp:  2             [SII]6731      7.407      0.36     -13    16
# Comp:  2              HeII4687     0.7577      0.36     -13    16
# Comp:  2               HeI5876     0.1741      0.36     -13    16
# Comp:  2          [OIII]5007_d      5.893      0.46     -13    16
# Comp:  2            [OI]6300_d     0.2597      0.46     -13    16
# Comp:  2           [NII]6583_d      7.878      0.46     -13    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        60
#  comp.  1:       -11        28
#  comp.  2:       -15        18
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.13      0.37     -11    28
# Comp:  1                Halpha      45.75      0.37     -11    28
# Comp:  2             [SII]6716      10.44      0.37     -15    18
# Comp:  2             [SII]6731      7.200      0.37     -15    18
# Comp:  2              HeII4687      1.051      0.37     -15    18
# Comp:  2               HeI5876    0.08155      0.37     -15    18
# Comp:  2          [OIII]5007_d      5.668      0.46     -15    18
# Comp:  2            [OI]6300_d     0.1616      0.46     -15    18
# Comp:  2           [NII]6583_d      7.777      0.46     -15    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -11        20
#  comp.  2:       -10        24
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.20      0.37     -11    20
# Comp:  1                Halpha      45.26      0.37     -11    20
# Comp:  2             [SII]6716      10.78      0.37     -10    24
# Comp:  2             [SII]6731      7.284      0.37     -10    24
# Comp:  2              HeII4687      1.142      0.37     -10    24
# Comp:  2               HeI5876     0.1189      0.37     -10    24
# Comp:  2          [OIII]5007_d      5.711      0.47     -10    24
# Comp:  2            [OI]6300_d      1.007      0.47     -10    24
# Comp:  2           [NII]6583_d      7.897      0.47     -10    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61         1
#  comp.  1:        -9        12
#  comp.  2:       -11        23
# chi2/DOF: 1.129; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.46      0.36      -9    12
# Comp:  1                Halpha      43.52      0.36      -9    12
# Comp:  2             [SII]6716      10.49      0.37     -11    23
# Comp:  2             [SII]6731      7.530      0.37     -11    23
# Comp:  2              HeII4687     0.8074      0.37     -11    23
# Comp:  2               HeI5876      0.000      0.37     -11    23
# Comp:  2          [OIII]5007_d      6.683      0.47     -11    23
# Comp:  2            [OI]6300_d     0.9691      0.47     -11    23
# Comp:  2           [NII]6583_d      7.905      0.47     -11    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        17
#  comp.  1:       -11        25
#  comp.  2:       -13         6
# chi2/DOF: 1.131; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.90      0.37     -11    25
# Comp:  1                Halpha      44.92      0.37     -11    25
# Comp:  2             [SII]6716      10.06      0.36     -13     6
# Comp:  2             [SII]6731      7.043      0.36     -13     6
# Comp:  2              HeII4687      1.328      0.36     -13     6
# Comp:  2               HeI5876      0.000      0.36     -13     6
# Comp:  2          [OIII]5007_d      5.502      0.45     -13     6
# Comp:  2            [OI]6300_d     0.1976      0.45     -13     6
# Comp:  2           [NII]6583_d      7.171      0.45     -13     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112      1000
#  comp.  1:        -6         8
#  comp.  2:       -12        28
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.36      -6     8
# Comp:  1                Halpha      41.64      0.36      -6     8
# Comp:  2             [SII]6716      11.08      0.37     -12    28
# Comp:  2             [SII]6731      7.128      0.37     -12    28
# Comp:  2              HeII4687     0.7269      0.37     -12    28
# Comp:  2               HeI5876    0.05123      0.37     -12    28
# Comp:  2          [OIII]5007_d      5.303      0.47     -12    28
# Comp:  2            [OI]6300_d     0.3263      0.47     -12    28
# Comp:  2           [NII]6583_d      8.124      0.47     -12    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        -8        18
#  comp.  2:       -10        25
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.70      0.37      -8    18
# Comp:  1                Halpha      43.79      0.37      -8    18
# Comp:  2             [SII]6716      10.63      0.37     -10    25
# Comp:  2             [SII]6731      7.228      0.37     -10    25
# Comp:  2              HeII4687     0.5933      0.37     -10    25
# Comp:  2               HeI5876      0.000      0.37     -10    25
# Comp:  2          [OIII]5007_d      5.805      0.47     -10    25
# Comp:  2            [OI]6300_d      1.139      0.47     -10    25
# Comp:  2           [NII]6583_d      7.993      0.47     -10    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        63
#  comp.  1:        -6         1
#  comp.  2:       -11        21
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.00      0.36      -6     1
# Comp:  1                Halpha      42.22      0.36      -6     1
# Comp:  2             [SII]6716      10.60      0.37     -11    21
# Comp:  2             [SII]6731      7.272      0.37     -11    21
# Comp:  2              HeII4687      1.197      0.37     -11    21
# Comp:  2               HeI5876     0.2211      0.37     -11    21
# Comp:  2          [OIII]5007_d      6.108      0.46     -11    21
# Comp:  2            [OI]6300_d     0.7192      0.46     -11    21
# Comp:  2           [NII]6583_d      7.588      0.46     -11    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        75         1
#  comp.  1:        -5         5
#  comp.  2:       -13        20
# chi2/DOF: 1.130; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.34      0.36      -5     5
# Comp:  1                Halpha      42.92      0.36      -5     5
# Comp:  2             [SII]6716      10.46      0.37     -13    20
# Comp:  2             [SII]6731      6.936      0.37     -13    20
# Comp:  2              HeII4687     0.9886      0.37     -13    20
# Comp:  2               HeI5876      0.000      0.37     -13    20
# Comp:  2          [OIII]5007_d      6.258      0.46     -13    20
# Comp:  2            [OI]6300_d     0.5860      0.46     -13    20
# Comp:  2           [NII]6583_d      8.022      0.46     -13    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        44
#  comp.  1:        -8         7
#  comp.  2:       -13        11
# chi2/DOF: 1.137; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.33      0.36      -8     7
# Comp:  1                Halpha      44.11      0.36      -8     7
# Comp:  2             [SII]6716      10.15      0.36     -13    11
# Comp:  2             [SII]6731      7.145      0.36     -13    11
# Comp:  2              HeII4687      1.028      0.36     -13    11
# Comp:  2               HeI5876     0.1736      0.36     -13    11
# Comp:  2          [OIII]5007_d      5.595      0.46     -13    11
# Comp:  2            [OI]6300_d     0.5825      0.46     -13    11
# Comp:  2           [NII]6583_d      7.281      0.46     -13    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9       686
#  comp.  1:        -6         1
#  comp.  2:       -11        19
# chi2/DOF: 1.137; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.15      0.36      -6     1
# Comp:  1                Halpha      41.43      0.36      -6     1
# Comp:  2             [SII]6716      10.60      0.37     -11    19
# Comp:  2             [SII]6731      7.012      0.37     -11    19
# Comp:  2              HeII4687     0.6210      0.37     -11    19
# Comp:  2               HeI5876      0.000      0.37     -11    19
# Comp:  2          [OIII]5007_d      5.581      0.46     -11    19
# Comp:  2            [OI]6300_d     0.6674      0.46     -11    19
# Comp:  2           [NII]6583_d      7.759      0.46     -11    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        56
#  comp.  1:        -9         8
#  comp.  2:       -14         1
# chi2/DOF: 1.134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.76      0.36      -9     8
# Comp:  1                Halpha      43.12      0.36      -9     8
# Comp:  2             [SII]6716      10.04      0.36     -14     1
# Comp:  2             [SII]6731      7.021      0.36     -14     1
# Comp:  2              HeII4687     0.9186      0.36     -14     1
# Comp:  2               HeI5876      0.000      0.36     -14     1
# Comp:  2          [OIII]5007_d      5.844      0.45     -14     1
# Comp:  2            [OI]6300_d     0.5215      0.45     -14     1
# Comp:  2           [NII]6583_d      7.089      0.45     -14     1
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
