# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00153

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22318852 2.22392739 2.22466626 ... 3.54133176 3.54207063 3.5428095 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
# chi2/DOF: 0.03450; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
# chi2/DOF: 0.02530; DOF: 1925; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([35.90717603,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:        40        87
#  comp.  2:       -16         1
# chi2/DOF: 6.471; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.323      0.46      40    87
# Comp:  1                Halpha      22.32      0.46      40    87
# Comp:  2             [SII]6716      4.325      0.36     -16     1
# Comp:  2             [SII]6731      192.2      0.36     -16     1
# Comp:  2              HeII4687     0.1334      0.36     -16     1
# Comp:  2               HeI5876     0.2211      0.36     -16     1
# Comp:  2          [OIII]5007_d      5.475      0.45     -16     1
# Comp:  2            [OI]6300_d      2.053      0.45     -16     1
# Comp:  2           [NII]6583_d      2.195      0.45     -16     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  9.847; gas flux:      7 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  29.42; gas flux:     31 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.005; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  426.9; gas flux:    270 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.2804; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.4725; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  9.079; gas flux:      6 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.464; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.567; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        49        52
#  comp.  1:        40        88
#  comp.  2:       -16         1
# chi2/DOF: 6.447; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.714      0.46      40    88
# Comp:  1                Halpha      22.34      0.46      40    88
# Comp:  2             [SII]6716      4.585      0.36     -16     1
# Comp:  2             [SII]6731      192.5      0.36     -16     1
# Comp:  2              HeII4687      0.000      0.36     -16     1
# Comp:  2               HeI5876     0.1787      0.36     -16     1
# Comp:  2          [OIII]5007_d      5.975      0.45     -16     1
# Comp:  2            [OI]6300_d      2.147      0.45     -16     1
# Comp:  2           [NII]6583_d      2.186      0.45     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        38        82
#  comp.  2:       -28        17
# chi2/DOF: 3.720; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.547      0.45      38    82
# Comp:  1                Halpha      21.96      0.45      38    82
# Comp:  2             [SII]6716      4.519      0.36     -28    17
# Comp:  2             [SII]6731      207.2      0.36     -28    17
# Comp:  2              HeII4687     0.5030      0.36     -28    17
# Comp:  2               HeI5876     0.1241      0.36     -28    17
# Comp:  2          [OIII]5007_d      5.459      0.46     -28    17
# Comp:  2            [OI]6300_d      1.895      0.46     -28    17
# Comp:  2           [NII]6583_d      2.551      0.46     -28    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
#  comp.  1:        36        83
#  comp.  2:        -4         1
# chi2/DOF: 3.363; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.081      0.45      36    83
# Comp:  1                Halpha      22.18      0.45      36    83
# Comp:  2             [SII]6716      4.117      0.36      -4     1
# Comp:  2             [SII]6731      204.2      0.36      -4     1
# Comp:  2              HeII4687     0.3272      0.36      -4     1
# Comp:  2               HeI5876     0.1446      0.36      -4     1
# Comp:  2          [OIII]5007_d      6.457      0.45      -4     1
# Comp:  2            [OI]6300_d      2.125      0.45      -4     1
# Comp:  2           [NII]6583_d      2.929      0.45      -4     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47        63
#  comp.  1:        44        93
#  comp.  2:        -6         1
# chi2/DOF: 3.752; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.340      0.47      44    93
# Comp:  1                Halpha      23.25      0.47      44    93
# Comp:  2             [SII]6716      5.171      0.36      -6     1
# Comp:  2             [SII]6731      208.1      0.36      -6     1
# Comp:  2              HeII4687     0.4105      0.36      -6     1
# Comp:  2               HeI5876     0.3222      0.36      -6     1
# Comp:  2          [OIII]5007_d      4.512      0.45      -6     1
# Comp:  2            [OI]6300_d      2.275      0.45      -6     1
# Comp:  2           [NII]6583_d      2.752      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:        40        88
#  comp.  2:       -23        41
# chi2/DOF: 3.882; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.127      0.46      40    88
# Comp:  1                Halpha      22.57      0.46      40    88
# Comp:  2             [SII]6716      5.585      0.39     -23    41
# Comp:  2             [SII]6731      213.5      0.39     -23    41
# Comp:  2              HeII4687     0.4555      0.39     -23    41
# Comp:  2               HeI5876     0.2338      0.39     -23    41
# Comp:  2          [OIII]5007_d      4.289      0.49     -23    41
# Comp:  2            [OI]6300_d      2.707      0.49     -23    41
# Comp:  2           [NII]6583_d      2.870      0.49     -23    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73         1
#  comp.  1:        47        86
#  comp.  2:        -6         1
# chi2/DOF: 3.766; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.179      0.46      47    86
# Comp:  1                Halpha      22.66      0.46      47    86
# Comp:  2             [SII]6716      4.859      0.36      -6     1
# Comp:  2             [SII]6731      208.1      0.36      -6     1
# Comp:  2              HeII4687      0.000      0.36      -6     1
# Comp:  2               HeI5876     0.2929      0.36      -6     1
# Comp:  2          [OIII]5007_d      5.435      0.45      -6     1
# Comp:  2            [OI]6300_d      2.244      0.45      -6     1
# Comp:  2           [NII]6583_d      1.729      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        72         1
#  comp.  1:        44        93
#  comp.  2:        -6         1
# chi2/DOF: 4.518; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.621      0.47      44    93
# Comp:  1                Halpha      22.25      0.47      44    93
# Comp:  2             [SII]6716      4.471      0.36      -6     1
# Comp:  2             [SII]6731      181.8      0.36      -6     1
# Comp:  2              HeII4687      0.000      0.36      -6     1
# Comp:  2               HeI5876     0.3082      0.36      -6     1
# Comp:  2          [OIII]5007_d      5.137      0.45      -6     1
# Comp:  2            [OI]6300_d      2.426      0.45      -6     1
# Comp:  2           [NII]6583_d      1.762      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35       229
#  comp.  1:        39        96
#  comp.  2:       -14         1
# chi2/DOF: 6.280; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.007      0.47      39    96
# Comp:  1                Halpha      23.73      0.47      39    96
# Comp:  2             [SII]6716      5.133      0.36     -14     1
# Comp:  2             [SII]6731      188.1      0.36     -14     1
# Comp:  2              HeII4687     0.5140      0.36     -14     1
# Comp:  2               HeI5876     0.3174      0.36     -14     1
# Comp:  2          [OIII]5007_d      5.348      0.45     -14     1
# Comp:  2            [OI]6300_d      2.173      0.45     -14     1
# Comp:  2           [NII]6583_d      2.164      0.45     -14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67        64
#  comp.  1:        37        98
#  comp.  2:        -9         1
# chi2/DOF: 5.428; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.086      0.48      37    98
# Comp:  1                Halpha      23.03      0.48      37    98
# Comp:  2             [SII]6716      4.478      0.36      -9     1
# Comp:  2             [SII]6731      185.9      0.36      -9     1
# Comp:  2              HeII4687     0.2701      0.36      -9     1
# Comp:  2               HeI5876     0.2920      0.36      -9     1
# Comp:  2          [OIII]5007_d      5.577      0.45      -9     1
# Comp:  2            [OI]6300_d      2.161      0.45      -9     1
# Comp:  2           [NII]6583_d      2.409      0.45      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        40        86
#  comp.  2:       -17        37
# chi2/DOF: 2.723; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.027      0.46      40    86
# Comp:  1                Halpha      22.57      0.46      40    86
# Comp:  2             [SII]6716      4.637      0.38     -17    37
# Comp:  2             [SII]6731      233.0      0.38     -17    37
# Comp:  2              HeII4687      0.000      0.38     -17    37
# Comp:  2               HeI5876     0.2516      0.38     -17    37
# Comp:  2          [OIII]5007_d      4.352      0.48     -17    37
# Comp:  2            [OI]6300_d      2.651      0.48     -17    37
# Comp:  2           [NII]6583_d      2.178      0.48     -17    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62       384
#  comp.  1:        39        81
#  comp.  2:        -6         1
# chi2/DOF: 4.277; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.745      0.45      39    81
# Comp:  1                Halpha      21.03      0.45      39    81
# Comp:  2             [SII]6716      4.889      0.36      -6     1
# Comp:  2             [SII]6731      202.5      0.36      -6     1
# Comp:  2              HeII4687      0.000      0.36      -6     1
# Comp:  2               HeI5876     0.4006      0.36      -6     1
# Comp:  2          [OIII]5007_d      5.564      0.45      -6     1
# Comp:  2            [OI]6300_d      1.609      0.45      -6     1
# Comp:  2           [NII]6583_d      2.892      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:        36        88
#  comp.  2:       -15        39
# chi2/DOF: 3.264; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.598      0.46      36    88
# Comp:  1                Halpha      22.41      0.46      36    88
# Comp:  2             [SII]6716      5.174      0.38     -15    39
# Comp:  2             [SII]6731      229.9      0.38     -15    39
# Comp:  2              HeII4687      0.000      0.38     -15    39
# Comp:  2               HeI5876     0.1815      0.38     -15    39
# Comp:  2          [OIII]5007_d      6.109      0.48     -15    39
# Comp:  2            [OI]6300_d      2.225      0.48     -15    39
# Comp:  2           [NII]6583_d      1.940      0.48     -15    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       105        43
#  comp.  1:        47        95
#  comp.  2:       -20        41
# chi2/DOF: 4.249; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.062      0.47      47    95
# Comp:  1                Halpha      23.46      0.47      47    95
# Comp:  2             [SII]6716      5.640      0.39     -20    41
# Comp:  2             [SII]6731      208.7      0.39     -20    41
# Comp:  2              HeII4687      0.000      0.39     -20    41
# Comp:  2               HeI5876     0.1217      0.39     -20    41
# Comp:  2          [OIII]5007_d      6.468      0.49     -20    41
# Comp:  2            [OI]6300_d      2.251      0.49     -20    41
# Comp:  2           [NII]6583_d      2.608      0.49     -20    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        80        54
#  comp.  1:        39        93
#  comp.  2:       -17        29
# chi2/DOF: 4.638; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.803      0.47      39    93
# Comp:  1                Halpha      23.99      0.47      39    93
# Comp:  2             [SII]6716      4.383      0.37     -17    29
# Comp:  2             [SII]6731      220.6      0.37     -17    29
# Comp:  2              HeII4687     0.2578      0.37     -17    29
# Comp:  2               HeI5876     0.3088      0.37     -17    29
# Comp:  2          [OIII]5007_d      4.618      0.47     -17    29
# Comp:  2            [OI]6300_d      1.918      0.47     -17    29
# Comp:  2           [NII]6583_d      2.605      0.47     -17    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        79       130
#  comp.  1:        38        86
#  comp.  2:       -31        40
# chi2/DOF: 1.883; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.654      0.46      38    86
# Comp:  1                Halpha      22.22      0.46      38    86
# Comp:  2             [SII]6716      4.938      0.38     -31    40
# Comp:  2             [SII]6731      202.1      0.38     -31    40
# Comp:  2              HeII4687     0.3150      0.38     -31    40
# Comp:  2               HeI5876     0.1226      0.38     -31    40
# Comp:  2          [OIII]5007_d      4.424      0.49     -31    40
# Comp:  2            [OI]6300_d      2.032      0.49     -31    40
# Comp:  2           [NII]6583_d      2.093      0.49     -31    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29         1
#  comp.  1:        39        82
#  comp.  2:        -3         1
# chi2/DOF: 3.890; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.552      0.45      39    82
# Comp:  1                Halpha      22.11      0.45      39    82
# Comp:  2             [SII]6716      4.821      0.36      -3     1
# Comp:  2             [SII]6731      183.8      0.36      -3     1
# Comp:  2              HeII4687     0.1908      0.36      -3     1
# Comp:  2               HeI5876     0.1378      0.36      -3     1
# Comp:  2          [OIII]5007_d      5.669      0.45      -3     1
# Comp:  2            [OI]6300_d      2.022      0.45      -3     1
# Comp:  2           [NII]6583_d      2.430      0.45      -3     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        54
#  comp.  1:        39        95
#  comp.  2:       -12         1
# chi2/DOF: 6.154; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.384      0.47      39    95
# Comp:  1                Halpha      24.01      0.47      39    95
# Comp:  2             [SII]6716      4.630      0.36     -12     1
# Comp:  2             [SII]6731      189.6      0.36     -12     1
# Comp:  2              HeII4687     0.2884      0.36     -12     1
# Comp:  2               HeI5876     0.2294      0.36     -12     1
# Comp:  2          [OIII]5007_d      5.298      0.45     -12     1
# Comp:  2            [OI]6300_d      2.316      0.45     -12     1
# Comp:  2           [NII]6583_d      2.163      0.45     -12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        38        84
#  comp.  2:       -15        39
# chi2/DOF: 3.196; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.186      0.45      38    84
# Comp:  1                Halpha      21.79      0.45      38    84
# Comp:  2             [SII]6716      5.278      0.38     -15    39
# Comp:  2             [SII]6731      230.3      0.38     -15    39
# Comp:  2              HeII4687      0.000      0.38     -15    39
# Comp:  2               HeI5876     0.1024      0.38     -15    39
# Comp:  2          [OIII]5007_d      5.381      0.48     -15    39
# Comp:  2            [OI]6300_d      1.948      0.48     -15    39
# Comp:  2           [NII]6583_d      1.930      0.48     -15    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        47
#  comp.  1:        36        99
#  comp.  2:        -8         1
# chi2/DOF: 4.548; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.977      0.48      36    99
# Comp:  1                Halpha      24.08      0.48      36    99
# Comp:  2             [SII]6716      4.332      0.36      -8     1
# Comp:  2             [SII]6731      206.4      0.36      -8     1
# Comp:  2              HeII4687     0.4189      0.36      -8     1
# Comp:  2               HeI5876     0.1171      0.36      -8     1
# Comp:  2          [OIII]5007_d      5.544      0.45      -8     1
# Comp:  2            [OI]6300_d      2.238      0.45      -8     1
# Comp:  2           [NII]6583_d      2.654      0.45      -8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        42        86
#  comp.  2:       -26        13
# chi2/DOF: 4.967; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.420      0.46      42    86
# Comp:  1                Halpha      21.83      0.46      42    86
# Comp:  2             [SII]6716      3.701      0.36     -26    13
# Comp:  2             [SII]6731      200.5      0.36     -26    13
# Comp:  2              HeII4687     0.3531      0.36     -26    13
# Comp:  2               HeI5876     0.1723      0.36     -26    13
# Comp:  2          [OIII]5007_d      5.456      0.45     -26    13
# Comp:  2            [OI]6300_d      2.143      0.45     -26    13
# Comp:  2           [NII]6583_d      2.074      0.45     -26    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28       104
#  comp.  1:        40        83
#  comp.  2:       -26        13
# chi2/DOF: 4.968; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.207      0.45      40    83
# Comp:  1                Halpha      21.42      0.45      40    83
# Comp:  2             [SII]6716      5.071      0.36     -26    13
# Comp:  2             [SII]6731      200.4      0.36     -26    13
# Comp:  2              HeII4687      0.000      0.36     -26    13
# Comp:  2               HeI5876     0.1955      0.36     -26    13
# Comp:  2          [OIII]5007_d      5.057      0.45     -26    13
# Comp:  2            [OI]6300_d      2.094      0.45     -26    13
# Comp:  2           [NII]6583_d      1.984      0.45     -26    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        38        91
#  comp.  2:       -31        37
# chi2/DOF: 2.397; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.557      0.46      38    91
# Comp:  1                Halpha      22.86      0.46      38    91
# Comp:  2             [SII]6716      4.627      0.38     -31    37
# Comp:  2             [SII]6731      199.6      0.38     -31    37
# Comp:  2              HeII4687      0.000      0.38     -31    37
# Comp:  2               HeI5876     0.4110      0.38     -31    37
# Comp:  2          [OIII]5007_d      5.701      0.48     -31    37
# Comp:  2            [OI]6300_d      2.143      0.48     -31    37
# Comp:  2           [NII]6583_d      2.532      0.48     -31    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       107        15
#  comp.  1:        45        84
#  comp.  2:       -26        24
# chi2/DOF: 4.141; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.441      0.45      45    84
# Comp:  1                Halpha      22.62      0.45      45    84
# Comp:  2             [SII]6716      5.007      0.37     -26    24
# Comp:  2             [SII]6731      211.3      0.37     -26    24
# Comp:  2              HeII4687    0.07308      0.37     -26    24
# Comp:  2               HeI5876     0.2822      0.37     -26    24
# Comp:  2          [OIII]5007_d      5.612      0.46     -26    24
# Comp:  2            [OI]6300_d      2.495      0.46     -26    24
# Comp:  2           [NII]6583_d      1.992      0.46     -26    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65        44
#  comp.  1:        41        95
#  comp.  2:       -20        50
# chi2/DOF: 2.149; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.651      0.47      41    95
# Comp:  1                Halpha      23.87      0.47      41    95
# Comp:  2             [SII]6716      4.584      0.40     -20    50
# Comp:  2             [SII]6731      223.6      0.40     -20    50
# Comp:  2              HeII4687      0.000      0.40     -20    50
# Comp:  2               HeI5876     0.1788      0.40     -20    50
# Comp:  2          [OIII]5007_d      6.120      0.50     -20    50
# Comp:  2            [OI]6300_d      2.280      0.50     -20    50
# Comp:  2           [NII]6583_d      3.326      0.50     -20    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:        40        92
#  comp.  2:       -20        41
# chi2/DOF: 4.255; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.972      0.47      40    92
# Comp:  1                Halpha      22.90      0.47      40    92
# Comp:  2             [SII]6716      4.939      0.39     -20    41
# Comp:  2             [SII]6731      208.7      0.39     -20    41
# Comp:  2              HeII4687      0.000      0.39     -20    41
# Comp:  2               HeI5876     0.4785      0.39     -20    41
# Comp:  2          [OIII]5007_d      6.026      0.49     -20    41
# Comp:  2            [OI]6300_d      2.233      0.49     -20    41
# Comp:  2           [NII]6583_d      2.496      0.49     -20    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:        42        85
#  comp.  2:       -31        37
# chi2/DOF: 2.379; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.232      0.45      42    85
# Comp:  1                Halpha      21.99      0.45      42    85
# Comp:  2             [SII]6716      4.157      0.38     -31    37
# Comp:  2             [SII]6731      199.5      0.38     -31    37
# Comp:  2              HeII4687      0.000      0.38     -31    37
# Comp:  2               HeI5876     0.3129      0.38     -31    37
# Comp:  2          [OIII]5007_d      6.450      0.48     -31    37
# Comp:  2            [OI]6300_d      2.341      0.48     -31    37
# Comp:  2           [NII]6583_d      2.538      0.48     -31    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:        39        94
#  comp.  2:       -16         1
# chi2/DOF: 6.431; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.640      0.47      39    94
# Comp:  1                Halpha      23.45      0.47      39    94
# Comp:  2             [SII]6716      5.063      0.36     -16     1
# Comp:  2             [SII]6731      192.5      0.36     -16     1
# Comp:  2              HeII4687     0.4936      0.36     -16     1
# Comp:  2               HeI5876    0.08323      0.36     -16     1
# Comp:  2          [OIII]5007_d      5.645      0.45     -16     1
# Comp:  2            [OI]6300_d      2.246      0.45     -16     1
# Comp:  2           [NII]6583_d      1.968      0.45     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        94        46
#  comp.  1:        41        87
#  comp.  2:        -6         1
# chi2/DOF: 4.588; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.235      0.46      41    87
# Comp:  1                Halpha      22.54      0.46      41    87
# Comp:  2             [SII]6716      4.516      0.36      -6     1
# Comp:  2             [SII]6731      181.9      0.36      -6     1
# Comp:  2              HeII4687     0.2240      0.36      -6     1
# Comp:  2               HeI5876     0.1776      0.36      -6     1
# Comp:  2          [OIII]5007_d      6.453      0.45      -6     1
# Comp:  2            [OI]6300_d      1.743      0.45      -6     1
# Comp:  2           [NII]6583_d      2.720      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:        41        76
#  comp.  2:       -26        13
# chi2/DOF: 4.968; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.419      0.44      41    76
# Comp:  1                Halpha      21.25      0.44      41    76
# Comp:  2             [SII]6716      4.692      0.36     -26    13
# Comp:  2             [SII]6731      200.4      0.36     -26    13
# Comp:  2              HeII4687      0.000      0.36     -26    13
# Comp:  2               HeI5876     0.3729      0.36     -26    13
# Comp:  2          [OIII]5007_d      6.373      0.45     -26    13
# Comp:  2            [OI]6300_d      2.143      0.45     -26    13
# Comp:  2           [NII]6583_d      2.132      0.45     -26    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        54
#  comp.  1:        42        86
#  comp.  2:       -25        29
# chi2/DOF: 4.847; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.630      0.46      42    86
# Comp:  1                Halpha      23.25      0.46      42    86
# Comp:  2             [SII]6716      5.159      0.37     -25    29
# Comp:  2             [SII]6731      209.1      0.37     -25    29
# Comp:  2              HeII4687     0.3198      0.37     -25    29
# Comp:  2               HeI5876     0.3820      0.37     -25    29
# Comp:  2          [OIII]5007_d      4.397      0.47     -25    29
# Comp:  2            [OI]6300_d      2.380      0.47     -25    29
# Comp:  2           [NII]6583_d      1.385      0.47     -25    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46       189
#  comp.  1:        40        88
#  comp.  2:       -16         1
# chi2/DOF: 4.285; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.096      0.46      40    88
# Comp:  1                Halpha      23.03      0.46      40    88
# Comp:  2             [SII]6716      4.923      0.36     -16     1
# Comp:  2             [SII]6731      167.7      0.36     -16     1
# Comp:  2              HeII4687      0.000      0.36     -16     1
# Comp:  2               HeI5876     0.1215      0.36     -16     1
# Comp:  2          [OIII]5007_d      4.834      0.45     -16     1
# Comp:  2            [OI]6300_d      2.647      0.45     -16     1
# Comp:  2           [NII]6583_d      1.903      0.45     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58        38
#  comp.  1:        39        82
#  comp.  2:       -23        44
# chi2/DOF: 3.371; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.219      0.45      39    82
# Comp:  1                Halpha      22.33      0.45      39    82
# Comp:  2             [SII]6716      4.127      0.39     -23    44
# Comp:  2             [SII]6731      216.2      0.39     -23    44
# Comp:  2              HeII4687    0.04335      0.39     -23    44
# Comp:  2               HeI5876     0.2319      0.39     -23    44
# Comp:  2          [OIII]5007_d      4.519      0.49     -23    44
# Comp:  2            [OI]6300_d      2.341      0.49     -23    44
# Comp:  2           [NII]6583_d      3.121      0.49     -23    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:        40        83
#  comp.  2:       -28        39
# chi2/DOF: 2.803; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.991      0.45      40    83
# Comp:  1                Halpha      21.36      0.45      40    83
# Comp:  2             [SII]6716      5.456      0.38     -28    39
# Comp:  2             [SII]6731      195.5      0.38     -28    39
# Comp:  2              HeII4687     0.1596      0.38     -28    39
# Comp:  2               HeI5876    0.04729      0.38     -28    39
# Comp:  2          [OIII]5007_d      5.819      0.48     -28    39
# Comp:  2            [OI]6300_d      2.124      0.48     -28    39
# Comp:  2           [NII]6583_d      2.541      0.48     -28    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        83        68
#  comp.  1:        46        81
#  comp.  2:       -26        13
# chi2/DOF: 4.973; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.830      0.45      46    81
# Comp:  1                Halpha      21.52      0.45      46    81
# Comp:  2             [SII]6716      4.694      0.36     -26    13
# Comp:  2             [SII]6731      200.4      0.36     -26    13
# Comp:  2              HeII4687     0.2806      0.36     -26    13
# Comp:  2               HeI5876     0.2434      0.36     -26    13
# Comp:  2          [OIII]5007_d      5.710      0.45     -26    13
# Comp:  2            [OI]6300_d      2.392      0.45     -26    13
# Comp:  2           [NII]6583_d      2.678      0.45     -26    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       102        66
#  comp.  1:        34        90
#  comp.  2:        -8         1
# chi2/DOF: 4.616; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.983      0.46      34    90
# Comp:  1                Halpha      22.60      0.46      34    90
# Comp:  2             [SII]6716      4.765      0.36      -8     1
# Comp:  2             [SII]6731      206.4      0.36      -8     1
# Comp:  2              HeII4687     0.3212      0.36      -8     1
# Comp:  2               HeI5876     0.1137      0.36      -8     1
# Comp:  2          [OIII]5007_d      5.255      0.45      -8     1
# Comp:  2            [OI]6300_d      1.880      0.45      -8     1
# Comp:  2           [NII]6583_d      2.529      0.45      -8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57         1
#  comp.  1:        38        92
#  comp.  2:       -31        31
# chi2/DOF: 2.782; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.044      0.47      38    92
# Comp:  1                Halpha      22.03      0.47      38    92
# Comp:  2             [SII]6716      5.097      0.37     -31    31
# Comp:  2             [SII]6731      189.1      0.37     -31    31
# Comp:  2              HeII4687     0.1060      0.37     -31    31
# Comp:  2               HeI5876     0.1017      0.37     -31    31
# Comp:  2          [OIII]5007_d      5.514      0.47     -31    31
# Comp:  2            [OI]6300_d      2.600      0.47     -31    31
# Comp:  2           [NII]6583_d      2.296      0.47     -31    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61         1
#  comp.  1:        41        91
#  comp.  2:       -32        34
# chi2/DOF: 2.399; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.927      0.46      41    91
# Comp:  1                Halpha      22.82      0.46      41    91
# Comp:  2             [SII]6716      4.625      0.38     -32    34
# Comp:  2             [SII]6731      191.3      0.38     -32    34
# Comp:  2              HeII4687      0.000      0.38     -32    34
# Comp:  2               HeI5876     0.1354      0.38     -32    34
# Comp:  2          [OIII]5007_d      6.480      0.48     -32    34
# Comp:  2            [OI]6300_d      2.163      0.48     -32    34
# Comp:  2           [NII]6583_d      1.783      0.48     -32    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       157
#  comp.  1:        40        87
#  comp.  2:       -16         1
# chi2/DOF: 4.318; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.067      0.46      40    87
# Comp:  1                Halpha      22.60      0.46      40    87
# Comp:  2             [SII]6716      4.507      0.36     -16     1
# Comp:  2             [SII]6731      167.8      0.36     -16     1
# Comp:  2              HeII4687     0.4437      0.36     -16     1
# Comp:  2               HeI5876     0.3543      0.36     -16     1
# Comp:  2          [OIII]5007_d      5.143      0.45     -16     1
# Comp:  2            [OI]6300_d      1.880      0.45     -16     1
# Comp:  2           [NII]6583_d      2.581      0.45     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:        41        93
#  comp.  2:       -20        42
# chi2/DOF: 4.200; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.606      0.47      41    93
# Comp:  1                Halpha      23.22      0.47      41    93
# Comp:  2             [SII]6716      4.298      0.39     -20    42
# Comp:  2             [SII]6731      209.0      0.39     -20    42
# Comp:  2              HeII4687      0.000      0.39     -20    42
# Comp:  2               HeI5876     0.2475      0.39     -20    42
# Comp:  2          [OIII]5007_d      7.018      0.49     -20    42
# Comp:  2            [OI]6300_d      1.996      0.49     -20    42
# Comp:  2           [NII]6583_d      2.359      0.49     -20    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        99
#  comp.  1:        41        90
#  comp.  2:        -4         1
# chi2/DOF: 3.276; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.718      0.46      41    90
# Comp:  1                Halpha      23.22      0.46      41    90
# Comp:  2             [SII]6716      5.257      0.36      -4     1
# Comp:  2             [SII]6731      204.3      0.36      -4     1
# Comp:  2              HeII4687     0.1449      0.36      -4     1
# Comp:  2               HeI5876     0.2176      0.36      -4     1
# Comp:  2          [OIII]5007_d      6.365      0.45      -4     1
# Comp:  2            [OI]6300_d      1.658      0.45      -4     1
# Comp:  2           [NII]6583_d      2.190      0.45      -4     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        91        44
#  comp.  1:        45        97
#  comp.  2:       -17        28
# chi2/DOF: 4.671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.749      0.47      45    97
# Comp:  1                Halpha      23.14      0.47      45    97
# Comp:  2             [SII]6716      4.231      0.37     -17    28
# Comp:  2             [SII]6731      220.2      0.37     -17    28
# Comp:  2              HeII4687      0.000      0.37     -17    28
# Comp:  2               HeI5876     0.2185      0.37     -17    28
# Comp:  2          [OIII]5007_d      6.636      0.47     -17    28
# Comp:  2            [OI]6300_d      2.139      0.47     -17    28
# Comp:  2           [NII]6583_d      2.733      0.47     -17    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60         1
#  comp.  1:        42        91
#  comp.  2:       -28        39
# chi2/DOF: 2.795; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.686      0.46      42    91
# Comp:  1                Halpha      22.06      0.46      42    91
# Comp:  2             [SII]6716      4.311      0.38     -28    39
# Comp:  2             [SII]6731      195.6      0.38     -28    39
# Comp:  2              HeII4687      0.000      0.38     -28    39
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.484      0.46      36    89
# Comp:  1                Halpha      23.31      0.46      36    89
# Comp:  2             [SII]6716      4.057      0.40     -20    50
# Comp:  2             [SII]6731      224.1      0.40     -20    50
# Comp:  2              HeII4687      0.000      0.40     -20    50
# Comp:  2               HeI5876     0.1742      0.40     -20    50
# Comp:  2          [OIII]5007_d      6.036      0.50     -20    50
# Comp:  2            [OI]6300_d      2.167      0.50     -20    50
# Comp:  2           [NII]6583_d      3.252      0.50     -20    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:        44        87
#  comp.  2:       -25        29
# chi2/DOF: 4.853; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.002      0.46      44    87
# Comp:  1                Halpha      22.99      0.46      44    87
# Comp:  2             [SII]6716      5.221      0.37     -25    29
# Comp:  2             [SII]6731      209.1      0.37     -25    29
# Comp:  2              HeII4687     0.1882      0.37     -25    29
# Comp:  2               HeI5876     0.4049      0.37     -25    29
# Comp:  2          [OIII]5007_d      5.633      0.47     -25    29
# Comp:  2            [OI]6300_d      1.657      0.47     -25    29
# Comp:  2           [NII]6583_d      2.531      0.47     -25    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        40        85
#  comp.  2:        -4         5
# chi2/DOF: 3.955; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.103      0.45      40    85
# Comp:  1                Halpha      21.22      0.45      40    85
# Comp:  2             [SII]6716      4.412      0.36      -4     5
# Comp:  2             [SII]6731      184.1      0.36      -4     5
# Comp:  2              HeII4687      0.000      0.36      -4     5
# Comp:  2               HeI5876    0.08151      0.36      -4     5
# Comp:  2          [OIII]5007_d      6.123      0.45      -4     5
# Comp:  2            [OI]6300_d      1.872      0.45      -4     5
# Comp:  2           [NII]6583_d      2.153      0.45      -4     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:        42        88
#  comp.  2:       -31        31
# chi2/DOF: 2.776; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.267      0.46      42    88
# Comp:  1                Halpha      23.15      0.46      42    88
# Comp:  2             [SII]6716      3.952      0.37     -31    31
# Comp:  2             [SII]6731      189.1      0.37     -31    31
# Comp:  2              HeII4687     0.3683      0.37     -31    31
# Comp:  2               HeI5876     0.2584      0.37     -31    31
# Comp:  2          [OIII]5007_d      5.983      0.47     -31    31
# Comp:  2            [OI]6300_d      1.841      0.47     -31    31
# Comp:  2           [NII]6583_d      2.581      0.47     -31    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
#  comp.  1:        35        86
#  comp.  2:       -14         1
# chi2/DOF: 6.393; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.475      0.46      35    86
# Comp:  1                Halpha      22.05      0.46      35    86
# Comp:  2             [SII]6716      4.893      0.36     -14     1
# Comp:  2             [SII]6731      193.8      0.36     -14     1
# Comp:  2              HeII4687     0.2865      0.36     -14     1
# Comp:  2               HeI5876     0.3396      0.36     -14     1
# Comp:  2          [OIII]5007_d      5.585      0.45     -14     1
# Comp:  2            [OI]6300_d      2.384      0.45     -14     1
# Comp:  2           [NII]6583_d      2.036      0.45     -14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52        83
#  comp.  1:        40        94
#  comp.  2:       -30        37
# chi2/DOF: 2.374; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.555      0.47      40    94
# Comp:  1                Halpha      23.33      0.47      40    94
# Comp:  2             [SII]6716      4.937      0.38     -30    37
# Comp:  2             [SII]6731      199.8      0.38     -30    37
# Comp:  2              HeII4687    0.04568      0.38     -30    37
# Comp:  2               HeI5876     0.1855      0.38     -30    37
# Comp:  2          [OIII]5007_d      6.906      0.48     -30    37
# Comp:  2            [OI]6300_d      2.516      0.48     -30    37
# Comp:  2           [NII]6583_d      2.532      0.48     -30    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:        42        83
#  comp.  2:       -31        31
# chi2/DOF: 2.778; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.500      0.45      42    83
# Comp:  1                Halpha      21.75      0.45      42    83
# Comp:  2             [SII]6716      4.149      0.37     -31    31
# Comp:  2             [SII]6731      189.0      0.37     -31    31
# Comp:  2              HeII4687     0.4903      0.37     -31    31
# Comp:  2               HeI5876     0.2265      0.37     -31    31
# Comp:  2          [OIII]5007_d      7.060      0.47     -31    31
# Comp:  2            [OI]6300_d      1.892      0.47     -31    31
# Comp:  2           [NII]6583_d      2.383      0.47     -31    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        64         1
#  comp.  1:        37        84
#  comp.  2:        -6         1
# chi2/DOF: 3.811; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.660      0.45      37    84
# Comp:  1                Halpha      22.35      0.45      37    84
# Comp:  2             [SII]6716      3.700      0.36      -6     1
# Comp:  2             [SII]6731      208.2      0.36      -6     1
# Comp:  2              HeII4687    0.04485      0.36      -6     1
# Comp:  2               HeI5876     0.2257      0.36      -6     1
# Comp:  2          [OIII]5007_d      6.082      0.45      -6     1
# Comp:  2            [OI]6300_d      2.372      0.45      -6     1
# Comp:  2           [NII]6583_d      2.350      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        14
#  comp.  1:        41        92
#  comp.  2:        -6         1
# chi2/DOF: 4.294; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.764      0.47      41    92
# Comp:  1                Halpha      22.52      0.47      41    92
# Comp:  2             [SII]6716      4.074      0.36      -6     1
# Comp:  2             [SII]6731      202.3      0.36      -6     1
# Comp:  2              HeII4687     0.2178      0.36      -6     1
# Comp:  2               HeI5876    0.07898      0.36      -6     1
# Comp:  2          [OIII]5007_d      5.335      0.45      -6     1
# Comp:  2            [OI]6300_d      2.173      0.45      -6     1
# Comp:  2           [NII]6583_d      2.410      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40        35
#  comp.  1:        33        89
#  comp.  2:       -23        44
# chi2/DOF: 3.374; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.615      0.46      33    89
# Comp:  1                Halpha      22.94      0.46      33    89
# Comp:  2             [SII]6716      5.138      0.39     -23    44
# Comp:  2             [SII]6731      216.2      0.39     -23    44
# Comp:  2              HeII4687      0.000      0.39     -23    44
# Comp:  2               HeI5876     0.1949      0.39     -23    44
# Comp:  2          [OIII]5007_d      5.939      0.49     -23    44
# Comp:  2            [OI]6300_d      2.310      0.49     -23    44
# Comp:  2           [NII]6583_d      2.855      0.49     -23    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77        26
#  comp.  1:        44        93
#  comp.  2:        -4         6
# chi2/DOF: 3.960; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.421      0.47      44    93
# Comp:  1                Halpha      23.06      0.47      44    93
# Comp:  2             [SII]6716      4.565      0.36      -4     6
# Comp:  2             [SII]6731      184.1      0.36      -4     6
# Comp:  2              HeII4687     0.2263      0.36      -4     6
# Comp:  2               HeI5876     0.1131      0.36      -4     6
# Comp:  2          [OIII]5007_d      4.997      0.45      -4     6
# Comp:  2            [OI]6300_d      1.874      0.45      -4     6
# Comp:  2           [NII]6583_d      2.308      0.45      -4     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65        50
#  comp.  1:        42        97
#  comp.  2:        -6         1
# chi2/DOF: 4.604; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.957      0.47      42    97
# Comp:  1                Halpha      23.13      0.47      42    97
# Comp:  2             [SII]6716      4.656      0.36      -6     1
# Comp:  2             [SII]6731      181.9      0.36      -6     1
# Comp:  2              HeII4687     0.4258      0.36      -6     1
# Comp:  2               HeI5876     0.2462      0.36      -6     1
# Comp:  2          [OIII]5007_d      4.811      0.45      -6     1
# Comp:  2            [OI]6300_d      1.692      0.45      -6     1
# Comp:  2           [NII]6583_d      1.759      0.45      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52        75
#  comp.  1:        36        90
#  comp.  2:        -3         1
# chi2/DOF: 3.886; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.117      0.46      36    90
# Comp:  1                Halpha      23.30      0.46      36    90
# Comp:  2             [SII]6716      4.469      0.36      -3     1
# Comp:  2             [SII]6731      183.7      0.36      -3     1
# Comp:  2              HeII4687      0.000      0.36      -3     1
# Comp:  2               HeI5876     0.2112      0.36      -3     1
# Comp:  2          [OIII]5007_d      5.277      0.45      -3     1
# Comp:  2            [OI]6300_d      2.052      0.45      -3     1
# Comp:  2           [NII]6583_d      2.339      0.45      -3     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        95
#  comp.  1:        35        96
#  comp.  2:       -20        47
# chi2/DOF: 2.695; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.680      0.47      35    96
# Comp:  1                Halpha      23.61      0.47      35    96
# Comp:  2             [SII]6716      4.436      0.39     -20    47
# Comp:  2             [SII]6731      221.0      0.39     -20    47
# Comp:  2              HeII4687    0.08434      0.39     -20    47
# Comp:  2               HeI5876     0.3433      0.39     -20    47
# Comp:  2          [OIII]5007_d      6.461      0.50     -20    47
# Comp:  2            [OI]6300_d      2.166      0.50     -20    47
# Comp:  2           [NII]6583_d      2.102      0.50     -20    47
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 0.93521708,  0.98347727,  0.64537839, 25.00823082,  0.18290126,
#         0.11570144,  0.76765201,  0.34115008,  0.50605862])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([7.42552168e+00, 3.05488538e+01, 6.05936316e+00, 2.69763531e+02,
#        1.30386680e-01, 2.70932365e-01, 5.71784282e+00, 2.69829437e+00,
#        3.01422004e+00])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_3_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_3_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_3_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.161920    0.020393
# 1        Halpha  0.666143    0.021446
# 2     [SII]6716  0.132130    0.014073
# 3     [SII]6731  5.882420    0.545325
# 4      HeII4687  0.002843    0.003988
# 5       HeI5876  0.005908    0.002523
# 6  [OIII]5007_d  0.124682    0.016739
# 7    [OI]6300_d  0.058839    0.007439
# 8   [NII]6583_d  0.065728    0.011035
#           Name      Flux  Error_flux
# 0        Hbeta  0.161920    0.020393
# 1       Halpha  0.666143    0.021446
# 2    [SII]6716  0.132130    0.014073
# 3    [SII]6731  5.882420    0.545325
# 4     HeII4687  0.002843    0.003988
# 5      HeI5876  0.005908    0.002523
# 6   [OIII]4959  0.031171    0.016739
# 7   [OIII]5007  0.093512    0.016739
# 8     [OI]6300  0.044129    0.007439
# 9     [OI]6364  0.014710    0.007439
# 10   [NII]6548  0.016432    0.011035
# 11   [NII]6583  0.049296    0.011035

# %%
np.median(flux_rf_rebin)
# Out:
# 0.021805839541947626
