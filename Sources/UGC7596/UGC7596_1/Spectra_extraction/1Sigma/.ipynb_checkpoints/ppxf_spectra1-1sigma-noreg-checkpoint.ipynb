# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt") 
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22238968 2.22312829 2.22386689 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
# chi2/DOF: 0.01215; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
# chi2/DOF: 0.009593; DOF: 1914; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [0.88354199 0.99160929 1.14931175 ... 0.84872    0.85480292 0.80943477]
# [0.99868912 1.00273007 0.99879762 ... 0.91818382 0.90901653 0.90285719]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-63.59939033,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        20
#  comp.  1:        21       180
#  comp.  2:        13       181
# chi2/DOF: 0.7909; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7341      0.42      21   180
# Comp:  1                Halpha      0.000      0.42      21   180
# Comp:  2             [SII]6716     0.4196      0.42      13   181
# Comp:  2             [SII]6731      0.000      0.42      13   181
# Comp:  2              HeII4687     0.2751      0.42      13   181
# Comp:  2               HeI5876      0.000      0.42      13   181
# Comp:  2          [OIII]5007_d     0.5635      0.53      13   181
# Comp:  2            [OI]6300_d     0.4762      0.53      13   181
# Comp:  2           [NII]6583_d     0.3011      0.53      13   181
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  0.941; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.5342; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  0.348; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.5365; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.4569; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.2889; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -26       245
#  comp.  2:        14        83
# chi2/DOF: 0.7827; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.582      0.48     -26   245
# Comp:  1                Halpha     0.4680      0.48     -26   245
# Comp:  2             [SII]6716     0.1012      0.31      14    83
# Comp:  2             [SII]6731     0.3758      0.31      14    83
# Comp:  2              HeII4687     0.5215      0.31      14    83
# Comp:  2               HeI5876      0.000      0.31      14    83
# Comp:  2          [OIII]5007_d     0.2783      0.40      14    83
# Comp:  2            [OI]6300_d      0.000      0.40      14    83
# Comp:  2           [NII]6583_d      0.000      0.40      14    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        79
#  comp.  1:        65       253
#  comp.  2:       -34       102
# chi2/DOF: 0.7815; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.366      0.49      65   253
# Comp:  1                Halpha     0.6212      0.49      65   253
# Comp:  2             [SII]6716     0.2899      0.34     -34   102
# Comp:  2             [SII]6731     0.3503      0.34     -34   102
# Comp:  2              HeII4687     0.8414      0.34     -34   102
# Comp:  2               HeI5876      0.000      0.34     -34   102
# Comp:  2          [OIII]5007_d     0.3574      0.42     -34   102
# Comp:  2            [OI]6300_d     0.8149      0.42     -34   102
# Comp:  2           [NII]6583_d      0.000      0.42     -34   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -78       158
#  comp.  2:       -71       232
# chi2/DOF: 0.7843; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3914      0.40     -78   158
# Comp:  1                Halpha      0.000      0.40     -78   158
# Comp:  2             [SII]6716     0.5041      0.48     -71   232
# Comp:  2             [SII]6731      0.000      0.48     -71   232
# Comp:  2              HeII4687      0.000      0.47     -71   232
# Comp:  2               HeI5876     0.1699      0.47     -71   232
# Comp:  2          [OIII]5007_d      1.061      0.60     -71   232
# Comp:  2            [OI]6300_d     0.6992      0.60     -71   232
# Comp:  2           [NII]6583_d      0.000      0.60     -71   232
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        74
#  comp.  1:        20       408
#  comp.  2:        78         1
# chi2/DOF: 0.7827; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.407      0.62      20   408
# Comp:  1                Halpha     0.4086      0.62      20   408
# Comp:  2             [SII]6716     0.1134      0.25      78     1
# Comp:  2             [SII]6731    0.02519      0.25      78     1
# Comp:  2              HeII4687     0.4290      0.25      78     1
# Comp:  2               HeI5876      0.000      0.25      78     1
# Comp:  2          [OIII]5007_d     0.3495      0.31      78     1
# Comp:  2            [OI]6300_d     0.4710      0.31      78     1
# Comp:  2           [NII]6583_d     0.6997      0.31      78     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        72
#  comp.  1:       101       461
#  comp.  2:       111       161
# chi2/DOF: 0.7826; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.963      0.66     101   461
# Comp:  1                Halpha    0.07741      0.67     101   461
# Comp:  2             [SII]6716     0.3581      0.40     111   161
# Comp:  2             [SII]6731      0.000      0.40     111   161
# Comp:  2              HeII4687     0.7027      0.40     111   161
# Comp:  2               HeI5876      0.000      0.40     111   161
# Comp:  2          [OIII]5007_d     0.2860      0.51     111   161
# Comp:  2            [OI]6300_d     0.7987      0.51     111   161
# Comp:  2           [NII]6583_d    0.04248      0.52     111   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:        -8       133
#  comp.  2:      -526         1
# chi2/DOF: 0.7633; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 96; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8566      0.37      -8   133
# Comp:  1                Halpha     0.5890      0.37      -8   133
# Comp:  2             [SII]6716      0.000      0.25    -526     1
# Comp:  2             [SII]6731      0.000      0.25    -526     1
# Comp:  2              HeII4687      0.000      0.25    -526     1
# Comp:  2               HeI5876    0.07420      0.25    -526     1
# Comp:  2          [OIII]5007_d     0.3751      0.31    -526     1
# Comp:  2            [OI]6300_d      2.249      0.31    -526     1
# Comp:  2           [NII]6583_d      0.000      0.31    -526     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        72
#  comp.  1:       -37       276
#  comp.  2:      -240       229
# chi2/DOF: 0.7815; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.717      0.51     -37   276
# Comp:  1                Halpha     0.8555      0.52     -37   276
# Comp:  2             [SII]6716     0.1713      0.48    -240   229
# Comp:  2             [SII]6731      0.000      0.48    -240   229
# Comp:  2              HeII4687     0.1521      0.47    -240   229
# Comp:  2               HeI5876      0.000      0.47    -240   229
# Comp:  2          [OIII]5007_d      1.077      0.59    -240   229
# Comp:  2            [OI]6300_d      1.334      0.59    -240   229
# Comp:  2           [NII]6583_d     0.2425      0.60    -240   229
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -58       101
#  comp.  2:       -72        41
# chi2/DOF: 0.7809; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8597      0.33     -58   101
# Comp:  1                Halpha     0.6785      0.33     -58   101
# Comp:  2             [SII]6716     0.4341      0.27     -72    41
# Comp:  2             [SII]6731     0.3723      0.27     -72    41
# Comp:  2              HeII4687     0.5940      0.27     -72    41
# Comp:  2               HeI5876      0.000      0.27     -72    41
# Comp:  2          [OIII]5007_d     0.2635      0.34     -72    41
# Comp:  2            [OI]6300_d    0.08217      0.34     -72    41
# Comp:  2           [NII]6583_d     0.1659      0.34     -72    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:      -145       551
#  comp.  2:      -721         1
# chi2/DOF: 0.7633; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 18; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.257      0.72    -145   551
# Comp:  1                Halpha    0.05077      0.78    -145   551
# Comp:  2             [SII]6716     0.2506      0.25    -721     1
# Comp:  2             [SII]6731     0.2471      0.25    -721     1
# Comp:  2              HeII4687      0.000      0.25    -721     1
# Comp:  2               HeI5876      0.000      0.25    -721     1
# Comp:  2          [OIII]5007_d      0.000      0.31    -721     1
# Comp:  2            [OI]6300_d      2.292      0.31    -721     1
# Comp:  2           [NII]6583_d     0.2344      0.34    -721     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:        -5       200
#  comp.  2:       -40        15
# chi2/DOF: 0.7805; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.182      0.44      -5   200
# Comp:  1                Halpha     0.4176      0.44      -5   200
# Comp:  2             [SII]6716     0.1079      0.25     -40    15
# Comp:  2             [SII]6731      0.000      0.25     -40    15
# Comp:  2              HeII4687   0.002282      0.25     -40    15
# Comp:  2               HeI5876     0.2824      0.25     -40    15
# Comp:  2          [OIII]5007_d     0.1336      0.32     -40    15
# Comp:  2            [OI]6300_d     0.2837      0.32     -40    15
# Comp:  2           [NII]6583_d     0.1269      0.32     -40    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:        45       162
#  comp.  2:       148       261
# chi2/DOF: 0.7826; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.404      0.40      45   162
# Comp:  1                Halpha     0.2925      0.40      45   162
# Comp:  2             [SII]6716     0.2103      0.52     148   261
# Comp:  2             [SII]6731   0.005448      0.52     148   261
# Comp:  2              HeII4687      1.057      0.50     148   261
# Comp:  2               HeI5876      0.000      0.50     148   261
# Comp:  2          [OIII]5007_d      1.584      0.63     148   261
# Comp:  2            [OI]6300_d      0.000      0.63     148   261
# Comp:  2           [NII]6583_d     0.7374      0.63     148   261
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        79
#  comp.  1:      -102       227
#  comp.  2:      -527         1
# chi2/DOF: 0.7597; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.913      0.47    -102   227
# Comp:  1                Halpha     0.3521      0.47    -102   227
# Comp:  2             [SII]6716     0.1007      0.25    -527     1
# Comp:  2             [SII]6731     0.1936      0.25    -527     1
# Comp:  2              HeII4687      0.000      0.25    -527     1
# Comp:  2               HeI5876     0.1719      0.25    -527     1
# Comp:  2          [OIII]5007_d     0.1605      0.31    -527     1
# Comp:  2            [OI]6300_d      2.359      0.31    -527     1
# Comp:  2           [NII]6583_d      0.000      0.31    -527     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -64       423
#  comp.  2:        94       166
# chi2/DOF: 0.7811; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.415      0.63     -64   423
# Comp:  1                Halpha      1.021      0.64     -64   423
# Comp:  2             [SII]6716     0.4042      0.41      94   166
# Comp:  2             [SII]6731      0.000      0.41      94   166
# Comp:  2              HeII4687    0.07028      0.41      94   166
# Comp:  2               HeI5876     0.1686      0.41      94   166
# Comp:  2          [OIII]5007_d    0.03029      0.51      94   166
# Comp:  2            [OI]6300_d     0.5105      0.51      94   166
# Comp:  2           [NII]6583_d      1.229      0.52      94   166
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        23
#  comp.  1:      -611      1000
#  comp.  2:       176       204
# chi2/DOF: 0.7781; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.930      0.96    -611  1000
# Comp:  1                Halpha      1.744       1.0    -611  1000
# Comp:  2             [SII]6716      1.347      0.45     176   204
# Comp:  2             [SII]6731    0.05065      0.45     176   204
# Comp:  2              HeII4687     0.5281      0.45     176   204
# Comp:  2               HeI5876     0.2643      0.45     176   204
# Comp:  2          [OIII]5007_d      1.111      0.56     176   204
# Comp:  2            [OI]6300_d     0.8194      0.56     176   204
# Comp:  2           [NII]6583_d      0.000      0.60     176   204
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -33       262
#  comp.  2:       149       207
# chi2/DOF: 0.7836; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.600      0.50     -33   262
# Comp:  1                Halpha     0.3540      0.50     -33   262
# Comp:  2             [SII]6716     0.6700      0.45     149   207
# Comp:  2             [SII]6731      0.000      0.45     149   207
# Comp:  2              HeII4687      0.000      0.45     149   207
# Comp:  2               HeI5876     0.1231      0.45     149   207
# Comp:  2          [OIII]5007_d     0.8472      0.57     149   207
# Comp:  2            [OI]6300_d     0.6870      0.57     149   207
# Comp:  2           [NII]6583_d     0.9378      0.57     149   207
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:         0        95
#  comp.  2:       -91       142
# chi2/DOF: 0.7836; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7386      0.33       0    95
# Comp:  1                Halpha      0.000      0.33       0    95
# Comp:  2             [SII]6716     0.4661      0.38     -91   142
# Comp:  2             [SII]6731      0.000      0.38     -91   142
# Comp:  2              HeII4687     0.8039      0.38     -91   142
# Comp:  2               HeI5876     0.3013      0.38     -91   142
# Comp:  2          [OIII]5007_d     0.4729      0.48     -91   142
# Comp:  2            [OI]6300_d     0.4350      0.48     -91   142
# Comp:  2           [NII]6583_d      0.000      0.48     -91   142
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:         1       259
#  comp.  2:        57       230
# chi2/DOF: 0.7830; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.133      0.50       1   259
# Comp:  1                Halpha     0.4004      0.50       1   259
# Comp:  2             [SII]6716     0.6054      0.48      57   230
# Comp:  2             [SII]6731     0.5865      0.48      57   230
# Comp:  2              HeII4687     0.6435      0.47      57   230
# Comp:  2               HeI5876      0.000      0.47      57   230
# Comp:  2          [OIII]5007_d     0.2971      0.60      57   230
# Comp:  2            [OI]6300_d      0.000      0.60      57   230
# Comp:  2           [NII]6583_d     0.9391      0.60      57   230
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        21
#  comp.  1:        59       225
#  comp.  2:      -602       130
# chi2/DOF: 0.7542; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.313      0.47      59   225
# Comp:  1                Halpha      0.000      0.55      59   225
# Comp:  2             [SII]6716     0.1351      0.37    -602   130
# Comp:  2             [SII]6731     0.4777      0.37    -602   130
# Comp:  2              HeII4687     0.2980      0.37    -602   130
# Comp:  2               HeI5876   0.004302      0.37    -602   130
# Comp:  2          [OIII]5007_d      0.000      0.46    -602   130
# Comp:  2            [OI]6300_d      3.663      0.46    -602   130
# Comp:  2           [NII]6583_d    0.04004      0.55    -602   130
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        31
#  comp.  1:        20       263
#  comp.  2:      -633        96
# chi2/DOF: 0.7407; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.608      0.50      20   263
# Comp:  1                Halpha      0.000      0.58      20   263
# Comp:  2             [SII]6716      0.000      0.33    -633    96
# Comp:  2             [SII]6731     0.4653      0.33    -633    96
# Comp:  2              HeII4687      0.000      0.33    -633    96
# Comp:  2               HeI5876      0.000      0.33    -633    96
# Comp:  2          [OIII]5007_d     0.4482      0.41    -633    96
# Comp:  2            [OI]6300_d      4.173      0.41    -633    96
# Comp:  2           [NII]6583_d     0.1498      0.48    -633    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:         7       209
#  comp.  2:       -46        90
# chi2/DOF: 0.7849; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.860      0.45       7   209
# Comp:  1                Halpha      0.000      0.45       7   209
# Comp:  2             [SII]6716    0.07004      0.32     -46    90
# Comp:  2             [SII]6731     0.5324      0.32     -46    90
# Comp:  2              HeII4687     0.5904      0.32     -46    90
# Comp:  2               HeI5876      0.000      0.32     -46    90
# Comp:  2          [OIII]5007_d     0.3102      0.41     -46    90
# Comp:  2            [OI]6300_d     0.3787      0.41     -46    90
# Comp:  2           [NII]6583_d     0.6149      0.41     -46    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:        21       180
#  comp.  2:       -65        95
# chi2/DOF: 0.7825; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.42      21   180
# Comp:  1                Halpha      0.000      0.42      21   180
# Comp:  2             [SII]6716     0.5019      0.33     -65    95
# Comp:  2             [SII]6731     0.5404      0.33     -65    95
# Comp:  2              HeII4687      0.000      0.33     -65    95
# Comp:  2               HeI5876      0.000      0.33     -65    95
# Comp:  2          [OIII]5007_d     0.2844      0.41     -65    95
# Comp:  2            [OI]6300_d     0.2281      0.41     -65    95
# Comp:  2           [NII]6583_d     0.3103      0.41     -65    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:        73       129
#  comp.  2:       132       251
# chi2/DOF: 0.7874; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7010      0.37      73   129
# Comp:  1                Halpha      0.000      0.37      73   129
# Comp:  2             [SII]6716     0.2576      0.50     132   251
# Comp:  2             [SII]6731      0.000      0.50     132   251
# Comp:  2              HeII4687     0.2676      0.49     132   251
# Comp:  2               HeI5876      0.000      0.49     132   251
# Comp:  2          [OIII]5007_d     0.1364      0.62     132   251
# Comp:  2            [OI]6300_d      0.000      0.62     132   251
# Comp:  2           [NII]6583_d      1.114      0.62     132   251
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        23
#  comp.  1:       -78       304
#  comp.  2:      -289       213
# chi2/DOF: 0.7813; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.460      0.54     -78   304
# Comp:  1                Halpha     0.9015      0.55     -78   304
# Comp:  2             [SII]6716     0.2004      0.46    -289   213
# Comp:  2             [SII]6731     0.4249      0.46    -289   213
# Comp:  2              HeII4687     0.5187      0.45    -289   213
# Comp:  2               HeI5876     0.3050      0.45    -289   213
# Comp:  2          [OIII]5007_d      1.044      0.57    -289   213
# Comp:  2            [OI]6300_d      0.000      0.57    -289   213
# Comp:  2           [NII]6583_d     0.5921      0.58    -289   213
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        38
#  comp.  1:       -43        92
#  comp.  2:       189       274
# chi2/DOF: 0.7816; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7803      0.32     -43    92
# Comp:  1                Halpha     0.5871      0.33     -43    92
# Comp:  2             [SII]6716     0.8401      0.53     189   274
# Comp:  2             [SII]6731      0.000      0.53     189   274
# Comp:  2              HeII4687     0.7124      0.51     189   274
# Comp:  2               HeI5876      0.000      0.51     189   274
# Comp:  2          [OIII]5007_d     0.1833      0.64     189   274
# Comp:  2            [OI]6300_d      1.782      0.64     189   274
# Comp:  2           [NII]6583_d      1.012      0.65     189   274
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:        38       185
#  comp.  2:        -4       220
# chi2/DOF: 0.7872; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9021      0.43      38   185
# Comp:  1                Halpha    0.09705      0.43      38   185
# Comp:  2             [SII]6716     0.3778      0.47      -4   220
# Comp:  2             [SII]6731      0.000      0.47      -4   220
# Comp:  2              HeII4687      0.000      0.46      -4   220
# Comp:  2               HeI5876    0.02370      0.46      -4   220
# Comp:  2          [OIII]5007_d    0.08521      0.58      -4   220
# Comp:  2            [OI]6300_d      0.000      0.58      -4   220
# Comp:  2           [NII]6583_d     0.1566      0.58      -4   220
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        97
#  comp.  1:        -7       256
#  comp.  2:       -15       161
# chi2/DOF: 0.7826; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.549      0.49      -7   256
# Comp:  1                Halpha     0.7696      0.50      -7   256
# Comp:  2             [SII]6716     0.3659      0.40     -15   161
# Comp:  2             [SII]6731     0.1132      0.40     -15   161
# Comp:  2              HeII4687      0.000      0.40     -15   161
# Comp:  2               HeI5876      0.000      0.40     -15   161
# Comp:  2          [OIII]5007_d     0.3846      0.51     -15   161
# Comp:  2            [OI]6300_d     0.2311      0.51     -15   161
# Comp:  2           [NII]6583_d     0.1773      0.51     -15   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        26
#  comp.  1:       -51       273
#  comp.  2:        33       157
# chi2/DOF: 0.7846; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.478      0.51     -51   273
# Comp:  1                Halpha     0.4536      0.51     -51   273
# Comp:  2             [SII]6716     0.2810      0.40      33   157
# Comp:  2             [SII]6731     0.1337      0.40      33   157
# Comp:  2              HeII4687      1.132      0.40      33   157
# Comp:  2               HeI5876    0.01894      0.40      33   157
# Comp:  2          [OIII]5007_d     0.6170      0.50      33   157
# Comp:  2            [OI]6300_d     0.7100      0.50      33   157
# Comp:  2           [NII]6583_d     0.5464      0.50      33   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        57
#  comp.  1:        27       154
#  comp.  2:       216       108
# chi2/DOF: 0.7757; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.571      0.39      27   154
# Comp:  1                Halpha      0.000      0.39      27   154
# Comp:  2             [SII]6716      0.000      0.34     216   108
# Comp:  2             [SII]6731     0.1927      0.34     216   108
# Comp:  2              HeII4687      1.191      0.34     216   108
# Comp:  2               HeI5876      0.000      0.34     216   108
# Comp:  2          [OIII]5007_d    0.06105      0.43     216   108
# Comp:  2            [OI]6300_d    0.04352      0.43     216   108
# Comp:  2           [NII]6583_d     0.6259      0.43     216   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        33
#  comp.  1:       110       218
#  comp.  2:        -3       137
# chi2/DOF: 0.7857; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.063      0.46     110   218
# Comp:  1                Halpha    0.05135      0.46     110   218
# Comp:  2             [SII]6716     0.6531      0.38      -3   137
# Comp:  2             [SII]6731     0.4918      0.38      -3   137
# Comp:  2              HeII4687      0.000      0.38      -3   137
# Comp:  2               HeI5876     0.1740      0.38      -3   137
# Comp:  2          [OIII]5007_d     0.6660      0.47      -3   137
# Comp:  2            [OI]6300_d     0.1541      0.47      -3   137
# Comp:  2           [NII]6583_d    0.08641      0.47      -3   137
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -46       230
#  comp.  2:       199       305
# chi2/DOF: 0.7804; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.202      0.47     -46   230
# Comp:  1                Halpha      0.000      0.48     -46   230
# Comp:  2             [SII]6716      1.267      0.57     199   305
# Comp:  2             [SII]6731    0.08709      0.57     199   305
# Comp:  2              HeII4687      0.000      0.54     199   305
# Comp:  2               HeI5876      0.000      0.54     199   305
# Comp:  2          [OIII]5007_d     0.6496      0.68     199   305
# Comp:  2            [OI]6300_d      0.000      0.68     199   305
# Comp:  2           [NII]6583_d      0.000      0.69     199   305
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105       104
#  comp.  1:        45       220
#  comp.  2:         2        59
# chi2/DOF: 0.7801; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9473      0.46      45   220
# Comp:  1                Halpha     0.4149      0.46      45   220
# Comp:  2             [SII]6716     0.4503      0.29       2    59
# Comp:  2             [SII]6731    0.03246      0.29       2    59
# Comp:  2              HeII4687     0.1238      0.29       2    59
# Comp:  2               HeI5876     0.4096      0.29       2    59
# Comp:  2          [OIII]5007_d     0.1381      0.36       2    59
# Comp:  2            [OI]6300_d    0.03541      0.36       2    59
# Comp:  2           [NII]6583_d     0.6603      0.36       2    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        49
#  comp.  1:       -49       282
#  comp.  2:       -31        61
# chi2/DOF: 0.7836; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.500      0.52     -49   282
# Comp:  1                Halpha     0.7075      0.52     -49   282
# Comp:  2             [SII]6716     0.2252      0.29     -31    61
# Comp:  2             [SII]6731      0.000      0.29     -31    61
# Comp:  2              HeII4687     0.2875      0.29     -31    61
# Comp:  2               HeI5876     0.3951      0.29     -31    61
# Comp:  2          [OIII]5007_d     0.2827      0.37     -31    61
# Comp:  2            [OI]6300_d     0.4539      0.37     -31    61
# Comp:  2           [NII]6583_d     0.2730      0.37     -31    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -49       131
#  comp.  2:       -63       189
# chi2/DOF: 0.7849; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7417      0.37     -49   131
# Comp:  1                Halpha      0.000      0.37     -49   131
# Comp:  2             [SII]6716     0.3454      0.43     -63   189
# Comp:  2             [SII]6731     0.1167      0.43     -63   189
# Comp:  2              HeII4687     0.5909      0.43     -63   189
# Comp:  2               HeI5876     0.3723      0.43     -63   189
# Comp:  2          [OIII]5007_d     0.5445      0.54     -63   189
# Comp:  2            [OI]6300_d     0.6817      0.54     -63   189
# Comp:  2           [NII]6583_d      0.000      0.54     -63   189
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        46
#  comp.  1:      -208       476
#  comp.  2:      -118       161
# chi2/DOF: 0.7827; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.786      0.67    -208   476
# Comp:  1                Halpha     0.7451      0.68    -208   476
# Comp:  2             [SII]6716     0.3335      0.40    -118   161
# Comp:  2             [SII]6731     0.7328      0.40    -118   161
# Comp:  2              HeII4687     0.8106      0.40    -118   161
# Comp:  2               HeI5876     0.1956      0.40    -118   161
# Comp:  2          [OIII]5007_d      0.000      0.51    -118   161
# Comp:  2            [OI]6300_d     0.5332      0.51    -118   161
# Comp:  2           [NII]6583_d     0.3669      0.52    -118   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         9
#  comp.  1:      2021       858
#  comp.  2:      -237       134
# chi2/DOF: 0.7780; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.89    2021   858
# Comp:  1                Halpha     0.9860      0.91    2021   858
# Comp:  2             [SII]6716    0.09251      0.37    -237   134
# Comp:  2             [SII]6731      0.000      0.37    -237   134
# Comp:  2              HeII4687     0.4250      0.37    -237   134
# Comp:  2               HeI5876      0.000      0.37    -237   134
# Comp:  2          [OIII]5007_d     0.9487      0.47    -237   134
# Comp:  2            [OI]6300_d     0.8605      0.47    -237   134
# Comp:  2           [NII]6583_d     0.2399      0.48    -237   134
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        38
#  comp.  1:       269       439
#  comp.  2:       107       183
# chi2/DOF: 0.7794; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.823      0.64     269   439
# Comp:  1                Halpha      0.000      0.67     269   439
# Comp:  2             [SII]6716      1.177      0.43     107   183
# Comp:  2             [SII]6731     0.3328      0.43     107   183
# Comp:  2              HeII4687     0.2610      0.42     107   183
# Comp:  2               HeI5876     0.1304      0.42     107   183
# Comp:  2          [OIII]5007_d     0.7800      0.54     107   183
# Comp:  2            [OI]6300_d     0.7642      0.54     107   183
# Comp:  2           [NII]6583_d      0.000      0.56     107   183
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        22
#  comp.  1:        16       147
#  comp.  2:        95        92
# chi2/DOF: 0.7847; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8162      0.39      16   147
# Comp:  1                Halpha      0.000      0.39      16   147
# Comp:  2             [SII]6716      0.000      0.32      95    92
# Comp:  2             [SII]6731      0.000      0.32      95    92
# Comp:  2              HeII4687     0.2930      0.32      95    92
# Comp:  2               HeI5876      0.000      0.32      95    92
# Comp:  2          [OIII]5007_d     0.4900      0.41      95    92
# Comp:  2            [OI]6300_d     0.2656      0.41      95    92
# Comp:  2           [NII]6583_d     0.8775      0.41      95    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        31
#  comp.  1:        17       121
#  comp.  2:        -5       121
# chi2/DOF: 0.7853; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.434      0.36      17   121
# Comp:  1                Halpha     0.3142      0.36      17   121
# Comp:  2             [SII]6716     0.1515      0.36      -5   121
# Comp:  2             [SII]6731    0.06897      0.36      -5   121
# Comp:  2              HeII4687     0.1419      0.36      -5   121
# Comp:  2               HeI5876      0.000      0.36      -5   121
# Comp:  2          [OIII]5007_d     0.6466      0.45      -5   121
# Comp:  2            [OI]6300_d    0.06101      0.45      -5   121
# Comp:  2           [NII]6583_d    0.04271      0.45      -5   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        58
#  comp.  1:       -29       274
#  comp.  2:      -525         1
# chi2/DOF: 0.7652; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 17; Func calls: 121; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.493      0.51     -29   274
# Comp:  1                Halpha     0.4186      0.52     -29   274
# Comp:  2             [SII]6716    0.06591      0.25    -525     1
# Comp:  2             [SII]6731    0.08020      0.25    -525     1
# Comp:  2              HeII4687      0.000      0.25    -525     1
# Comp:  2               HeI5876      0.000      0.25    -525     1
# Comp:  2          [OIII]5007_d      0.000      0.31    -525     1
# Comp:  2            [OI]6300_d      2.256      0.31    -525     1
# Comp:  2           [NII]6583_d    0.01337      0.32    -525     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:        27       279
#  comp.  2:       295         1
# chi2/DOF: 0.7745; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.429      0.52      27   279
# Comp:  1                Halpha     0.7569      0.52      27   279
# Comp:  2             [SII]6716      0.000      0.25     295     1
# Comp:  2             [SII]6731    0.05403      0.25     295     1
# Comp:  2              HeII4687      1.058      0.25     295     1
# Comp:  2               HeI5876     0.3658      0.25     295     1
# Comp:  2          [OIII]5007_d     0.1363      0.31     295     1
# Comp:  2            [OI]6300_d     0.2223      0.31     295     1
# Comp:  2           [NII]6583_d      0.000      0.31     295     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        39
#  comp.  1:      -124       284
#  comp.  2:      -102       366
# chi2/DOF: 0.7805; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.003      0.52    -124   284
# Comp:  1                Halpha      0.000      0.53    -124   284
# Comp:  2             [SII]6716     0.6328      0.67    -102   366
# Comp:  2             [SII]6731     0.1034      0.67    -102   366
# Comp:  2              HeII4687      0.000      0.59    -102   366
# Comp:  2               HeI5876   0.004368      0.59    -102   366
# Comp:  2          [OIII]5007_d      1.202      0.74    -102   366
# Comp:  2            [OI]6300_d      2.189      0.74    -102   366
# Comp:  2           [NII]6583_d    0.04343      0.76    -102   366
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         7
#  comp.  1:      -127       255
#  comp.  2:       -13       184
# chi2/DOF: 0.7869; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.592      0.49    -127   255
# Comp:  1                Halpha     0.2209      0.50    -127   255
# Comp:  2             [SII]6716     0.2776      0.43     -13   184
# Comp:  2             [SII]6731    0.09339      0.43     -13   184
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.532      0.58      42   356
# Comp:  1                Halpha     0.1975      0.63      42   356
# Comp:  2             [SII]6716     0.6671      0.80      30   440
# Comp:  2             [SII]6731     0.1915      0.80      30   440
# Comp:  2              HeII4687      1.556      0.64      30   440
# Comp:  2               HeI5876     0.1723      0.64      30   440
# Comp:  2          [OIII]5007_d      1.449      0.81      30   440
# Comp:  2            [OI]6300_d     0.7348      0.81      30   440
# Comp:  2           [NII]6583_d    0.08661      0.88      30   440
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:     -1474        60
#  comp.  2:      -142       229
# chi2/DOF: 0.7776; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2270      0.29   -1474    60
# Comp:  1                Halpha     0.4252      0.29   -1474    60
# Comp:  2             [SII]6716     0.5341      0.48    -142   229
# Comp:  2             [SII]6731     0.6835      0.48    -142   229
# Comp:  2              HeII4687     0.5735      0.47    -142   229
# Comp:  2               HeI5876      0.000      0.47    -142   229
# Comp:  2          [OIII]5007_d      0.000      0.59    -142   229
# Comp:  2            [OI]6300_d      1.243      0.59    -142   229
# Comp:  2           [NII]6583_d      0.000      0.59    -142   229
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        93
#  comp.  1:       -96       348
#  comp.  2:       232       529
# chi2/DOF: 0.7769; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.331      0.57     -96   348
# Comp:  1                Halpha      1.380      0.62     -96   348
# Comp:  2             [SII]6716      0.000      0.98     232   529
# Comp:  2             [SII]6731     0.4219      0.98     232   529
# Comp:  2              HeII4687      2.173      0.70     232   529
# Comp:  2               HeI5876      1.093      0.70     232   529
# Comp:  2          [OIII]5007_d      1.443      0.89     232   529
# Comp:  2            [OI]6300_d      2.110      0.89     232   529
# Comp:  2           [NII]6583_d      1.010      0.93     232   529
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -24       177
#  comp.  2:        23       169
# chi2/DOF: 0.7863; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.864      0.42     -24   177
# Comp:  1                Halpha     0.2206      0.42     -24   177
# Comp:  2             [SII]6716     0.6392      0.41      23   169
# Comp:  2             [SII]6731     0.4164      0.41      23   169
# Comp:  2              HeII4687     0.2141      0.41      23   169
# Comp:  2               HeI5876     0.3068      0.41      23   169
# Comp:  2          [OIII]5007_d     0.3660      0.52      23   169
# Comp:  2            [OI]6300_d      0.000      0.52      23   169
# Comp:  2           [NII]6583_d     0.4617      0.52      23   169
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        27
#  comp.  1:        52        45
#  comp.  2:       -47       308
# chi2/DOF: 0.7828; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4756      0.27      52    45
# Comp:  1                Halpha      0.000      0.27      52    45
# Comp:  2             [SII]6716     0.7184      0.58     -47   308
# Comp:  2             [SII]6731     0.2151      0.58     -47   308
# Comp:  2              HeII4687      1.002      0.54     -47   308
# Comp:  2               HeI5876      0.000      0.54     -47   308
# Comp:  2          [OIII]5007_d      1.932      0.68     -47   308
# Comp:  2            [OI]6300_d    0.08720      0.68     -47   308
# Comp:  2           [NII]6583_d      0.000      0.68     -47   308
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        46
#  comp.  1:       155        80
#  comp.  2:       -25       166
# chi2/DOF: 0.7838; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4829      0.31     155    80
# Comp:  1                Halpha      0.000      0.31     155    80
# Comp:  2             [SII]6716     0.2373      0.41     -25   166
# Comp:  2             [SII]6731     0.1335      0.41     -25   166
# Comp:  2              HeII4687     0.4470      0.41     -25   166
# Comp:  2               HeI5876      0.000      0.41     -25   166
# Comp:  2          [OIII]5007_d     0.3834      0.51     -25   166
# Comp:  2            [OI]6300_d     0.2942      0.51     -25   166
# Comp:  2           [NII]6583_d      0.000      0.51     -25   166
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -13       296
#  comp.  2:      -684        10
# chi2/DOF: 0.7413; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.038      0.53     -13   296
# Comp:  1                Halpha      0.000      0.58     -13   296
# Comp:  2             [SII]6716     0.2732      0.25    -684    10
# Comp:  2             [SII]6731     0.2715      0.25    -684    10
# Comp:  2              HeII4687    0.05431      0.25    -684    10
# Comp:  2               HeI5876    0.05044      0.25    -684    10
# Comp:  2          [OIII]5007_d     0.2232      0.31    -684    10
# Comp:  2            [OI]6300_d      3.037      0.31    -684    10
# Comp:  2           [NII]6583_d      0.000      0.35    -684    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        38
#  comp.  1:        29       181
#  comp.  2:       115       159
# chi2/DOF: 0.7838; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.576      0.42      29   181
# Comp:  1                Halpha     0.6996      0.42      29   181
# Comp:  2             [SII]6716     0.4998      0.40     115   159
# Comp:  2             [SII]6731      0.000      0.40     115   159
# Comp:  2              HeII4687     0.7726      0.40     115   159
# Comp:  2               HeI5876     0.3933      0.40     115   159
# Comp:  2          [OIII]5007_d     0.6289      0.50     115   159
# Comp:  2            [OI]6300_d    0.08090      0.50     115   159
# Comp:  2           [NII]6583_d      0.000      0.50     115   159
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        46
#  comp.  1:       -24       313
#  comp.  2:        45       208
# chi2/DOF: 0.7835; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.522      0.54     -24   313
# Comp:  1                Halpha     0.5632      0.55     -24   313
# Comp:  2             [SII]6716      0.000      0.45      45   208
# Comp:  2             [SII]6731      0.000      0.45      45   208
# Comp:  2              HeII4687     0.4334      0.45      45   208
# Comp:  2               HeI5876     0.6734      0.45      45   208
# Comp:  2          [OIII]5007_d      1.005      0.57      45   208
# Comp:  2            [OI]6300_d     0.5437      0.57      45   208
# Comp:  2           [NII]6583_d     0.3416      0.57      45   208
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       298         1
#  comp.  2:       207       147
# chi2/DOF: 0.7795; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2339      0.25     298     1
# Comp:  1                Halpha     0.3385      0.25     298     1
# Comp:  2             [SII]6716     0.7383      0.39     207   147
# Comp:  2             [SII]6731     0.1092      0.39     207   147
# Comp:  2              HeII4687      0.000      0.39     207   147
# Comp:  2               HeI5876      0.000      0.39     207   147
# Comp:  2          [OIII]5007_d      1.199      0.49     207   147
# Comp:  2            [OI]6300_d      1.075      0.49     207   147
# Comp:  2           [NII]6583_d     0.5265      0.49     207   147
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:        28       404
#  comp.  2:       231        82
# chi2/DOF: 0.7818; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.185      0.62      28   404
# Comp:  1                Halpha     0.6665      0.62      28   404
# Comp:  2             [SII]6716      0.000      0.31     231    82
# Comp:  2             [SII]6731      0.000      0.31     231    82
# Comp:  2              HeII4687      1.132      0.31     231    82
# Comp:  2               HeI5876      0.000      0.31     231    82
# Comp:  2          [OIII]5007_d      0.000      0.39     231    82
# Comp:  2            [OI]6300_d      0.000      0.39     231    82
# Comp:  2           [NII]6583_d     0.5265      0.40     231    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        62
#  comp.  1:       -82       296
#  comp.  2:       198       226
# chi2/DOF: 0.7782; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.851      0.53     -82   296
# Comp:  1                Halpha     0.7297      0.54     -82   296
# Comp:  2             [SII]6716      0.000      0.47     198   226
# Comp:  2             [SII]6731      0.000      0.47     198   226
# Comp:  2              HeII4687     0.8402      0.47     198   226
# Comp:  2               HeI5876     0.4648      0.47     198   226
# Comp:  2          [OIII]5007_d     0.8736      0.59     198   226
# Comp:  2            [OI]6300_d     0.6510      0.59     198   226
# Comp:  2           [NII]6583_d      0.000      0.60     198   226
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        22
#  comp.  1:        56       208
#  comp.  2:        43       157
# chi2/DOF: 0.7864; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8512      0.45      56   208
# Comp:  1                Halpha     0.8482      0.45      56   208
# Comp:  2             [SII]6716     0.2511      0.40      43   157
# Comp:  2             [SII]6731      0.000      0.40      43   157
# Comp:  2              HeII4687     0.5894      0.40      43   157
# Comp:  2               HeI5876      0.000      0.40      43   157
# Comp:  2          [OIII]5007_d     0.5425      0.50      43   157
# Comp:  2            [OI]6300_d     0.1326      0.50      43   157
# Comp:  2           [NII]6583_d    0.01366      0.50      43   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:        -8       302
#  comp.  2:      -101       206
# chi2/DOF: 0.7852; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.964      0.54      -8   302
# Comp:  1                Halpha     0.6571      0.54      -8   302
# Comp:  2             [SII]6716     0.4379      0.45    -101   206
# Comp:  2             [SII]6731      0.000      0.45    -101   206
# Comp:  2              HeII4687     0.4796      0.45    -101   206
# Comp:  2               HeI5876     0.3002      0.45    -101   206
# Comp:  2          [OIII]5007_d     0.8078      0.56    -101   206
# Comp:  2            [OI]6300_d     0.8842      0.56    -101   206
# Comp:  2           [NII]6583_d      0.000      0.57    -101   206
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.50622427, 0.54265308, 0.44094576, 0.29531054, 0.4821721 ,
#        0.30680048, 0.5094898 , 1.20252452, 0.50639617])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.74433112, 0.        , 0.5877896 , 0.        , 0.26890778,
#        0.        , 0.58851868, 0.62580155, 0.41352444])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_1_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_1_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_1_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.029181    0.059050
# 1        Halpha  0.000000    0.021274
# 2     [SII]6716  0.023044    0.017287
# 3     [SII]6731  0.000000    0.011577
# 4      HeII4687  0.010542    0.018903
# 5       HeI5876  0.000000    0.012028
# 6  [OIII]5007_d  0.023072    0.019974
# 7    [OI]6300_d  0.024534    0.047144
# 8   [NII]6583_d  0.016212    0.019853
#           Name      Flux  Error_flux
# 0        Hbeta  0.029181    0.059050
# 1       Halpha  0.000000    0.021274
# 2    [SII]6716  0.023044    0.017287
# 3    [SII]6731  0.000000    0.011577
# 4     HeII4687  0.010542    0.018903
# 5      HeI5876  0.000000    0.012028
# 6   [OIII]4959  0.005768    0.019974
# 7   [OIII]5007  0.017304    0.019974
# 8     [OI]6300  0.018401    0.047144
# 9     [OI]6364  0.006134    0.047144
# 10   [NII]6548  0.004053    0.019853
# 11   [NII]6583  0.012159    0.019853

# %%
np.median(flux_rf_rebin)
# Out:
# 0.039204215400639085
