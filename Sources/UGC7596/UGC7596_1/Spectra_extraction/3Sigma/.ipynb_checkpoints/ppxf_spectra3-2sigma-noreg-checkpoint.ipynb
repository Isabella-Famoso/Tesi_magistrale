# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00153

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22318852 2.22392739 2.22466626 ... 3.54133176 3.54207063 3.5428095 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        37         1
# chi2/DOF: 0.01839; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
# chi2/DOF: 0.01148; DOF: 1923; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        27        35
#  comp.  1:        32        56
#  comp.  2:       -29        13
# chi2/DOF: 1.577; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.732      0.28      32    56
# Comp:  1                Halpha      18.59      0.28      32    56
# Comp:  2             [SII]6716      4.640      0.25     -29    13
# Comp:  2             [SII]6731      90.85      0.25     -29    13
# Comp:  2              HeII4687     0.4358      0.25     -29    13
# Comp:  2               HeI5876     0.1206      0.25     -29    13
# Comp:  2          [OIII]5007_d      3.531      0.31     -29    13
# Comp:  2            [OI]6300_d      1.636      0.31     -29    13
# Comp:  2           [NII]6583_d      1.766      0.31     -29    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        16
#  comp.  1:        32        56
#  comp.  2:       -26         1
# chi2/DOF: 1.481; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.902      0.28      32    56
# Comp:  1                Halpha      18.62      0.28      32    56
# Comp:  2             [SII]6716      4.109      0.25     -26     1
# Comp:  2             [SII]6731      83.59      0.25     -26     1
# Comp:  2              HeII4687     0.2005      0.25     -26     1
# Comp:  2               HeI5876     0.2616      0.25     -26     1
# Comp:  2          [OIII]5007_d      3.934      0.31     -26     1
# Comp:  2            [OI]6300_d      1.683      0.31     -26     1
# Comp:  2           [NII]6583_d      1.908      0.31     -26     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22        45
#  comp.  1:        30        56
#  comp.  2:       -27        29
# chi2/DOF: 1.401; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.186      0.28      30    56
# Comp:  1                Halpha      18.68      0.28      30    56
# Comp:  2             [SII]6716      3.074      0.26     -27    29
# Comp:  2             [SII]6731      94.05      0.26     -27    29
# Comp:  2              HeII4687     0.1851      0.26     -27    29
# Comp:  2               HeI5876     0.4435      0.26     -27    29
# Comp:  2          [OIII]5007_d      3.600      0.33     -27    29
# Comp:  2            [OI]6300_d      1.527      0.33     -27    29
# Comp:  2           [NII]6583_d      2.625      0.33     -27    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:        30        53
#  comp.  2:       -30        18
# chi2/DOF: 1.429; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.943      0.28      30    53
# Comp:  1                Halpha      17.80      0.28      30    53
# Comp:  2             [SII]6716      4.737      0.25     -30    18
# Comp:  2             [SII]6731      87.54      0.25     -30    18
# Comp:  2              HeII4687     0.2582      0.25     -30    18
# Comp:  2               HeI5876     0.2226      0.25     -30    18
# Comp:  2          [OIII]5007_d      4.391      0.32     -30    18
# Comp:  2            [OI]6300_d      1.453      0.32     -30    18
# Comp:  2           [NII]6583_d      2.441      0.32     -30    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58        38
#  comp.  1:        31        51
#  comp.  2:       -29         1
# chi2/DOF: 1.584; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.547      0.28      31    51
# Comp:  1                Halpha      17.72      0.28      31    51
# Comp:  2             [SII]6716      4.217      0.25     -29     1
# Comp:  2             [SII]6731      89.75      0.25     -29     1
# Comp:  2              HeII4687     0.3636      0.25     -29     1
# Comp:  2               HeI5876     0.2992      0.25     -29     1
# Comp:  2          [OIII]5007_d      4.469      0.31     -29     1
# Comp:  2            [OI]6300_d      1.449      0.31     -29     1
# Comp:  2           [NII]6583_d      2.348      0.31     -29     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59        62
#  comp.  1:        29        54
#  comp.  2:       -21         1
# chi2/DOF: 1.475; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.708      0.28      29    54
# Comp:  1                Halpha      18.07      0.28      29    54
# Comp:  2             [SII]6716      4.181      0.25     -21     1
# Comp:  2             [SII]6731      91.97      0.25     -21     1
# Comp:  2              HeII4687     0.4466      0.25     -21     1
# Comp:  2               HeI5876     0.2580      0.25     -21     1
# Comp:  2          [OIII]5007_d      4.150      0.31     -21     1
# Comp:  2            [OI]6300_d      1.300      0.31     -21     1
# Comp:  2           [NII]6583_d      2.004      0.31     -21     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40         1
#  comp.  1:        31        55
#  comp.  2:       -31        12
# chi2/DOF: 1.393; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.669      0.28      31    55
# Comp:  1                Halpha      17.85      0.28      31    55
# Comp:  2             [SII]6716      4.424      0.25     -31    12
# Comp:  2             [SII]6731      86.45      0.25     -31    12
# Comp:  2              HeII4687     0.3044      0.25     -31    12
# Comp:  2               HeI5876     0.1921      0.25     -31    12
# Comp:  2          [OIII]5007_d      4.280      0.31     -31    12
# Comp:  2            [OI]6300_d      1.757      0.31     -31    12
# Comp:  2           [NII]6583_d      2.158      0.31     -31    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63        32
#  comp.  1:        30        55
#  comp.  2:       -32        17
# chi2/DOF: 1.341; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.502      0.28      30    55
# Comp:  1                Halpha      18.17      0.28      30    55
# Comp:  2             [SII]6716      3.590      0.25     -32    17
# Comp:  2             [SII]6731      87.31      0.25     -32    17
# Comp:  2              HeII4687     0.2358      0.25     -32    17
# Comp:  2               HeI5876     0.3431      0.25     -32    17
# Comp:  2          [OIII]5007_d      4.905      0.32     -32    17
# Comp:  2            [OI]6300_d      1.463      0.32     -32    17
# Comp:  2           [NII]6583_d      1.802      0.32     -32    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        31
#  comp.  1:        30        51
#  comp.  2:       -26         1
# chi2/DOF: 1.474; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.820      0.28      30    51
# Comp:  1                Halpha      18.13      0.28      30    51
# Comp:  2             [SII]6716      3.591      0.25     -26     1
# Comp:  2             [SII]6731      83.77      0.25     -26     1
# Comp:  2              HeII4687     0.3964      0.25     -26     1
# Comp:  2               HeI5876     0.3113      0.25     -26     1
# Comp:  2          [OIII]5007_d      4.177      0.31     -26     1
# Comp:  2            [OI]6300_d      1.303      0.31     -26     1
# Comp:  2           [NII]6583_d      2.328      0.31     -26     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:        30        53
#  comp.  2:       -26        26
# chi2/DOF: 1.510; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.350      0.28      30    53
# Comp:  1                Halpha      17.89      0.28      30    53
# Comp:  2             [SII]6716      3.567      0.26     -26    26
# Comp:  2             [SII]6731      91.91      0.26     -26    26
# Comp:  2              HeII4687     0.2430      0.26     -26    26
# Comp:  2               HeI5876     0.3073      0.26     -26    26
# Comp:  2          [OIII]5007_d      5.124      0.32     -26    26
# Comp:  2            [OI]6300_d      1.352      0.32     -26    26
# Comp:  2           [NII]6583_d      2.016      0.32     -26    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        99
#  comp.  1:        31        55
#  comp.  2:       -18         1
# chi2/DOF: 1.318; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.012      0.28      31    55
# Comp:  1                Halpha      18.35      0.28      31    55
# Comp:  2             [SII]6716      4.725      0.25     -18     1
# Comp:  2             [SII]6731      90.98      0.25     -18     1
# Comp:  2              HeII4687     0.3198      0.25     -18     1
# Comp:  2               HeI5876     0.2331      0.25     -18     1
# Comp:  2          [OIII]5007_d      4.923      0.31     -18     1
# Comp:  2            [OI]6300_d      1.047      0.31     -18     1
# Comp:  2           [NII]6583_d      1.524      0.31     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40        73
#  comp.  1:        33        60
#  comp.  2:       -24        19
# chi2/DOF: 1.515; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.235      0.29      33    60
# Comp:  1                Halpha      18.47      0.29      33    60
# Comp:  2             [SII]6716      3.668      0.25     -24    19
# Comp:  2             [SII]6731      94.45      0.25     -24    19
# Comp:  2              HeII4687     0.3014      0.25     -24    19
# Comp:  2               HeI5876     0.2348      0.25     -24    19
# Comp:  2          [OIII]5007_d      5.001      0.32     -24    19
# Comp:  2            [OI]6300_d      1.343      0.32     -24    19
# Comp:  2           [NII]6583_d      2.171      0.32     -24    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32         1
#  comp.  1:        30        53
#  comp.  2:       -30        18
# chi2/DOF: 1.425; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.654      0.28      30    53
# Comp:  1                Halpha      17.79      0.28      30    53
# Comp:  2             [SII]6716      3.350      0.25     -30    18
# Comp:  2             [SII]6731      87.62      0.25     -30    18
# Comp:  2              HeII4687     0.1571      0.25     -30    18
# Comp:  2               HeI5876     0.2333      0.25     -30    18
# Comp:  2          [OIII]5007_d      3.763      0.32     -30    18
# Comp:  2            [OI]6300_d      1.354      0.32     -30    18
# Comp:  2           [NII]6583_d      1.788      0.32     -30    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        21
#  comp.  1:        30        57
#  comp.  2:       -21         1
# chi2/DOF: 1.525; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.487      0.28      30    57
# Comp:  1                Halpha      18.71      0.28      30    57
# Comp:  2             [SII]6716      2.823      0.25     -21     1
# Comp:  2             [SII]6731      86.69      0.25     -21     1
# Comp:  2              HeII4687     0.2638      0.25     -21     1
# Comp:  2               HeI5876     0.1248      0.25     -21     1
# Comp:  2          [OIII]5007_d      4.096      0.31     -21     1
# Comp:  2            [OI]6300_d      1.376      0.31     -21     1
# Comp:  2           [NII]6583_d      2.086      0.31     -21     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:        32        55
#  comp.  2:       -25         1
# chi2/DOF: 1.677; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.873      0.28      32    55
# Comp:  1                Halpha      18.54      0.28      32    55
# Comp:  2             [SII]6716      4.998      0.25     -25     1
# Comp:  2             [SII]6731      88.91      0.25     -25     1
# Comp:  2              HeII4687     0.2103      0.25     -25     1
# Comp:  2               HeI5876     0.3473      0.25     -25     1
# Comp:  2          [OIII]5007_d      4.064      0.31     -25     1
# Comp:  2            [OI]6300_d      1.554      0.31     -25     1
# Comp:  2           [NII]6583_d      2.420      0.31     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38         1
#  comp.  1:        32        56
#  comp.  2:       -28         5
# chi2/DOF: 1.620; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.952      0.28      32    56
# Comp:  1                Halpha      18.29      0.28      32    56
# Comp:  2             [SII]6716      3.745      0.25     -28     5
# Comp:  2             [SII]6731      90.02      0.25     -28     5
# Comp:  2              HeII4687     0.2656      0.25     -28     5
# Comp:  2               HeI5876    0.08512      0.25     -28     5
# Comp:  2          [OIII]5007_d      4.553      0.31     -28     5
# Comp:  2            [OI]6300_d      1.241      0.31     -28     5
# Comp:  2           [NII]6583_d      2.271      0.31     -28     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:        30        57
#  comp.  2:       -22         1
# chi2/DOF: 1.597; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.701      0.28      30    57
# Comp:  1                Halpha      18.83      0.28      30    57
# Comp:  2             [SII]6716      3.467      0.25     -22     1
# Comp:  2             [SII]6731      87.74      0.25     -22     1
# Comp:  2              HeII4687     0.3692      0.25     -22     1
# Comp:  2               HeI5876     0.1668      0.25     -22     1
# Comp:  2          [OIII]5007_d      4.550      0.31     -22     1
# Comp:  2            [OI]6300_d      1.092      0.31     -22     1
# Comp:  2           [NII]6583_d      2.717      0.31     -22     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53         1
#  comp.  1:        34        58
#  comp.  2:       -24        27
# chi2/DOF: 1.361; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.102      0.28      34    58
# Comp:  1                Halpha      18.80      0.28      34    58
# Comp:  2             [SII]6716      3.658      0.26     -24    27
# Comp:  2             [SII]6731      96.66      0.26     -24    27
# Comp:  2              HeII4687     0.4403      0.26     -24    27
# Comp:  2               HeI5876     0.1941      0.26     -24    27
# Comp:  2          [OIII]5007_d      3.598      0.32     -24    27
# Comp:  2            [OI]6300_d      1.444      0.32     -24    27
# Comp:  2           [NII]6583_d      1.954      0.32     -24    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        22
#  comp.  1:        29        57
#  comp.  2:       -26         1
# chi2/DOF: 1.504; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.075      0.28      29    57
# Comp:  1                Halpha      18.13      0.28      29    57
# Comp:  2             [SII]6716      4.443      0.25     -26     1
# Comp:  2             [SII]6731      83.92      0.25     -26     1
# Comp:  2              HeII4687     0.3057      0.25     -26     1
# Comp:  2               HeI5876     0.3117      0.25     -26     1
# Comp:  2          [OIII]5007_d      4.062      0.31     -26     1
# Comp:  2            [OI]6300_d      1.265      0.31     -26     1
# Comp:  2           [NII]6583_d      1.677      0.31     -26     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        35
#  comp.  1:        31        55
#  comp.  2:       -25         1
# chi2/DOF: 1.502; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.027      0.28      31    55
# Comp:  1                Halpha      18.22      0.28      31    55
# Comp:  2             [SII]6716      3.804      0.25     -25     1
# Comp:  2             [SII]6731      83.84      0.25     -25     1
# Comp:  2              HeII4687     0.2187      0.25     -25     1
# Comp:  2               HeI5876     0.3322      0.25     -25     1
# Comp:  2          [OIII]5007_d      4.328      0.31     -25     1
# Comp:  2            [OI]6300_d      1.462      0.31     -25     1
# Comp:  2           [NII]6583_d      2.087      0.31     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:        32        55
#  comp.  2:       -25         1
# chi2/DOF: 1.671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.164      0.28      32    55
# Comp:  1                Halpha      18.46      0.28      32    55
# Comp:  2             [SII]6716      2.926      0.25     -25     1
# Comp:  2             [SII]6731      89.17      0.25     -25     1
# Comp:  2              HeII4687     0.1928      0.25     -25     1
# Comp:  2               HeI5876     0.1667      0.25     -25     1
# Comp:  2          [OIII]5007_d      3.745      0.31     -25     1
# Comp:  2            [OI]6300_d      1.347      0.31     -25     1
# Comp:  2           [NII]6583_d      2.403      0.31     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63         1
#  comp.  1:        34        58
#  comp.  2:       -20         1
# chi2/DOF: 1.496; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.504      0.28      34    58
# Comp:  1                Halpha      18.58      0.28      34    58
# Comp:  2             [SII]6716      3.473      0.25     -20     1
# Comp:  2             [SII]6731      86.61      0.25     -20     1
# Comp:  2              HeII4687     0.1524      0.25     -20     1
# Comp:  2               HeI5876     0.2778      0.25     -20     1
# Comp:  2          [OIII]5007_d      5.221      0.31     -20     1
# Comp:  2            [OI]6300_d      1.672      0.31     -20     1
# Comp:  2           [NII]6583_d      2.540      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        44
#  comp.  1:        29        54
#  comp.  2:       -20         1
# chi2/DOF: 1.388; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.528      0.28      29    54
# Comp:  1                Halpha      18.14      0.28      29    54
# Comp:  2             [SII]6716      3.808      0.25     -20     1
# Comp:  2             [SII]6731      92.18      0.25     -20     1
# Comp:  2              HeII4687     0.2469      0.25     -20     1
# Comp:  2               HeI5876     0.1252      0.25     -20     1
# Comp:  2          [OIII]5007_d      4.337      0.31     -20     1
# Comp:  2            [OI]6300_d      1.179      0.31     -20     1
# Comp:  2           [NII]6583_d      1.979      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46        34
#  comp.  1:        30        56
#  comp.  2:       -31        22
# chi2/DOF: 1.356; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.750      0.28      30    56
# Comp:  1                Halpha      18.17      0.28      30    56
# Comp:  2             [SII]6716      3.584      0.25     -31    22
# Comp:  2             [SII]6731      88.50      0.25     -31    22
# Comp:  2              HeII4687     0.3421      0.25     -31    22
# Comp:  2               HeI5876     0.3824      0.25     -31    22
# Comp:  2          [OIII]5007_d      3.611      0.32     -31    22
# Comp:  2            [OI]6300_d      1.769      0.32     -31    22
# Comp:  2           [NII]6583_d      2.503      0.32     -31    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        71        76
#  comp.  1:        32        59
#  comp.  2:       -26         1
# chi2/DOF: 1.472; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.458      0.29      32    59
# Comp:  1                Halpha      18.92      0.29      32    59
# Comp:  2             [SII]6716      4.979      0.25     -26     1
# Comp:  2             [SII]6731      83.74      0.25     -26     1
# Comp:  2              HeII4687     0.4428      0.25     -26     1
# Comp:  2               HeI5876     0.2027      0.25     -26     1
# Comp:  2          [OIII]5007_d      3.602      0.31     -26     1
# Comp:  2            [OI]6300_d      1.355      0.31     -26     1
# Comp:  2           [NII]6583_d      1.715      0.31     -26     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        22
#  comp.  1:        30        51
#  comp.  2:       -21         1
# chi2/DOF: 1.532; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.131      0.28      30    51
# Comp:  1                Halpha      17.79      0.28      30    51
# Comp:  2             [SII]6716      3.526      0.25     -21     1
# Comp:  2             [SII]6731      86.70      0.25     -21     1
# Comp:  2              HeII4687     0.2332      0.25     -21     1
# Comp:  2               HeI5876     0.3117      0.25     -21     1
# Comp:  2          [OIII]5007_d      4.371      0.31     -21     1
# Comp:  2            [OI]6300_d      1.278      0.31     -21     1
# Comp:  2           [NII]6583_d      2.085      0.31     -21     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        29
#  comp.  1:        30        57
#  comp.  2:       -20        15
# chi2/DOF: 1.462; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.660      0.28      30    57
# Comp:  1                Halpha      18.32      0.28      30    57
# Comp:  2             [SII]6716      4.720      0.25     -20    15
# Comp:  2             [SII]6731      87.99      0.25     -20    15
# Comp:  2              HeII4687     0.2753      0.25     -20    15
# Comp:  2               HeI5876     0.1838      0.25     -20    15
# Comp:  2          [OIII]5007_d      4.380      0.32     -20    15
# Comp:  2            [OI]6300_d      1.660      0.32     -20    15
# Comp:  2           [NII]6583_d      1.954      0.32     -20    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40        35
#  comp.  1:        31        55
#  comp.  2:       -24         1
# chi2/DOF: 1.667; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.999      0.28      31    55
# Comp:  1                Halpha      17.91      0.28      31    55
# Comp:  2             [SII]6716      3.198      0.25     -24     1
# Comp:  2             [SII]6731      87.63      0.25     -24     1
# Comp:  2              HeII4687     0.2213      0.25     -24     1
# Comp:  2               HeI5876     0.3406      0.25     -24     1
# Comp:  2          [OIII]5007_d      3.735      0.31     -24     1
# Comp:  2            [OI]6300_d      1.414      0.31     -24     1
# Comp:  2           [NII]6583_d      2.212      0.31     -24     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44         1
#  comp.  1:        33        60
#  comp.  2:       -26         1
# chi2/DOF: 1.504; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.547      0.29      33    60
# Comp:  1                Halpha      18.79      0.29      33    60
# Comp:  2             [SII]6716      2.917      0.25     -26     1
# Comp:  2             [SII]6731      83.95      0.25     -26     1
# Comp:  2              HeII4687     0.2274      0.25     -26     1
# Comp:  2               HeI5876     0.1832      0.25     -26     1
# Comp:  2          [OIII]5007_d      4.382      0.31     -26     1
# Comp:  2            [OI]6300_d      1.657      0.31     -26     1
# Comp:  2           [NII]6583_d      1.874      0.31     -26     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55         1
#  comp.  1:        29        57
#  comp.  2:       -20         1
# chi2/DOF: 1.403; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.071      0.28      29    57
# Comp:  1                Halpha      18.24      0.28      29    57
# Comp:  2             [SII]6716      3.411      0.25     -20     1
# Comp:  2             [SII]6731      92.16      0.25     -20     1
# Comp:  2              HeII4687     0.3288      0.25     -20     1
# Comp:  2               HeI5876     0.1477      0.25     -20     1
# Comp:  2          [OIII]5007_d      4.524      0.31     -20     1
# Comp:  2            [OI]6300_d      1.433      0.31     -20     1
# Comp:  2           [NII]6583_d      1.717      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        18
#  comp.  1:        28        54
#  comp.  2:       -27         1
# chi2/DOF: 1.534; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.876      0.28      28    54
# Comp:  1                Halpha      18.23      0.28      28    54
# Comp:  2             [SII]6716      2.906      0.25     -27     1
# Comp:  2             [SII]6731      84.94      0.25     -27     1
# Comp:  2              HeII4687     0.4339      0.25     -27     1
# Comp:  2               HeI5876    0.08901      0.25     -27     1
# Comp:  2          [OIII]5007_d      4.334      0.31     -27     1
# Comp:  2            [OI]6300_d      1.268      0.31     -27     1
# Comp:  2           [NII]6583_d      2.375      0.31     -27     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68         1
#  comp.  1:        31        59
#  comp.  2:       -31        23
# chi2/DOF: 1.354; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.664      0.29      31    59
# Comp:  1                Halpha      18.19      0.29      31    59
# Comp:  2             [SII]6716      4.251      0.25     -31    23
# Comp:  2             [SII]6731      88.62      0.25     -31    23
# Comp:  2              HeII4687     0.3436      0.25     -31    23
# Comp:  2               HeI5876     0.1939      0.25     -31    23
# Comp:  2          [OIII]5007_d      4.416      0.32     -31    23
# Comp:  2            [OI]6300_d      1.308      0.32     -31    23
# Comp:  2           [NII]6583_d      1.983      0.32     -31    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        30        53
#  comp.  2:       -32        21
# chi2/DOF: 1.326; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.179      0.28      30    53
# Comp:  1                Halpha      18.11      0.28      30    53
# Comp:  2             [SII]6716      3.773      0.25     -32    21
# Comp:  2             [SII]6731      89.60      0.25     -32    21
# Comp:  2              HeII4687     0.3459      0.25     -32    21
# Comp:  2               HeI5876     0.3054      0.25     -32    21
# Comp:  2          [OIII]5007_d      4.600      0.32     -32    21
# Comp:  2            [OI]6300_d      1.654      0.32     -32    21
# Comp:  2           [NII]6583_d      1.857      0.32     -32    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        33        62
#  comp.  2:       -21         9
# chi2/DOF: 1.561; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.727      0.29      33    62
# Comp:  1                Halpha      19.22      0.29      33    62
# Comp:  2             [SII]6716      3.479      0.25     -21     9
# Comp:  2             [SII]6731      88.37      0.25     -21     9
# Comp:  2              HeII4687     0.3573      0.25     -21     9
# Comp:  2               HeI5876     0.2480      0.25     -21     9
# Comp:  2          [OIII]5007_d      4.119      0.31     -21     9
# Comp:  2            [OI]6300_d      1.521      0.31     -21     9
# Comp:  2           [NII]6583_d      1.368      0.31     -21     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56         1
#  comp.  1:        33        55
#  comp.  2:       -18         1
# chi2/DOF: 1.325; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.572      0.28      33    55
# Comp:  1                Halpha      18.18      0.28      33    55
# Comp:  2             [SII]6716      3.244      0.25     -18     1
# Comp:  2             [SII]6731      90.98      0.25     -18     1
# Comp:  2              HeII4687     0.3214      0.25     -18     1
# Comp:  2               HeI5876     0.1872      0.25     -18     1
# Comp:  2          [OIII]5007_d      3.854      0.31     -18     1
# Comp:  2            [OI]6300_d      1.388      0.31     -18     1
# Comp:  2           [NII]6583_d      2.387      0.31     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39         1
#  comp.  1:        31        54
#  comp.  2:       -18         1
# chi2/DOF: 1.337; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.896      0.28      31    54
# Comp:  1                Halpha      18.09      0.28      31    54
# Comp:  2             [SII]6716      3.501      0.25     -18     1
# Comp:  2             [SII]6731      90.96      0.25     -18     1
# Comp:  2              HeII4687     0.4358      0.25     -18     1
# Comp:  2               HeI5876     0.2344      0.25     -18     1
# Comp:  2          [OIII]5007_d      3.785      0.31     -18     1
# Comp:  2            [OI]6300_d      1.439      0.31     -18     1
# Comp:  2           [NII]6583_d      1.849      0.31     -18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53        84
#  comp.  1:        31        61
#  comp.  2:       -20         1
# chi2/DOF: 1.447; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.125      0.29      31    61
# Comp:  1                Halpha      18.81      0.29      31    61
# Comp:  2             [SII]6716      3.854      0.25     -20     1
# Comp:  2             [SII]6731      91.84      0.25     -20     1
# Comp:  2              HeII4687     0.2865      0.25     -20     1
# Comp:  2               HeI5876     0.3176      0.25     -20     1
# Comp:  2          [OIII]5007_d      3.779      0.31     -20     1
# Comp:  2            [OI]6300_d      1.312      0.31     -20     1
# Comp:  2           [NII]6583_d      2.488      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56        44
#  comp.  1:        30        55
#  comp.  2:       -24        27
# chi2/DOF: 1.348; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.950      0.28      30    55
# Comp:  1                Halpha      18.61      0.28      30    55
# Comp:  2             [SII]6716      3.632      0.26     -24    27
# Comp:  2             [SII]6731      96.67      0.26     -24    27
# Comp:  2              HeII4687     0.2263      0.26     -24    27
# Comp:  2               HeI5876     0.2056      0.26     -24    27
# Comp:  2          [OIII]5007_d      5.164      0.32     -24    27
# Comp:  2            [OI]6300_d      1.340      0.32     -24    27
# Comp:  2           [NII]6583_d      1.764      0.32     -24    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41         1
#  comp.  1:        32        57
#  comp.  2:       -30        11
# chi2/DOF: 1.493; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.129      0.28      32    57
# Comp:  1                Halpha      18.29      0.28      32    57
# Comp:  2             [SII]6716      4.689      0.25     -30    11
# Comp:  2             [SII]6731      91.98      0.25     -30    11
# Comp:  2              HeII4687     0.3523      0.25     -30    11
# Comp:  2               HeI5876     0.2255      0.25     -30    11
# Comp:  2          [OIII]5007_d      4.483      0.31     -30    11
# Comp:  2            [OI]6300_d      1.516      0.31     -30    11
# Comp:  2           [NII]6583_d      1.850      0.31     -30    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39         1
#  comp.  1:        29        56
#  comp.  2:       -23        24
# chi2/DOF: 1.423; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.954      0.28      29    56
# Comp:  1                Halpha      18.47      0.28      29    56
# Comp:  2             [SII]6716      4.256      0.25     -23    24
# Comp:  2             [SII]6731      95.65      0.25     -23    24
# Comp:  2              HeII4687     0.3700      0.25     -23    24
# Comp:  2               HeI5876     0.2367      0.25     -23    24
# Comp:  2          [OIII]5007_d      4.208      0.32     -23    24
# Comp:  2            [OI]6300_d      1.291      0.32     -23    24
# Comp:  2           [NII]6583_d      1.995      0.32     -23    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29         1
#  comp.  1:        33        62
#  comp.  2:       -27         1
# chi2/DOF: 1.540; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.871      0.29      33    62
# Comp:  1                Halpha      18.82      0.29      33    62
# Comp:  2             [SII]6716      4.079      0.25     -27     1
# Comp:  2             [SII]6731      85.01      0.25     -27     1
# Comp:  2              HeII4687     0.2004      0.25     -27     1
# Comp:  2               HeI5876     0.3018      0.25     -27     1
# Comp:  2          [OIII]5007_d      4.084      0.31     -27     1
# Comp:  2            [OI]6300_d      1.423      0.31     -27     1
# Comp:  2           [NII]6583_d      2.051      0.31     -27     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        69        36
#  comp.  1:        30        57
#  comp.  2:       -25         1
# chi2/DOF: 1.680; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.984      0.28      30    57
# Comp:  1                Halpha      18.41      0.28      30    57
# Comp:  2             [SII]6716      3.200      0.25     -25     1
# Comp:  2             [SII]6731      89.12      0.25     -25     1
# Comp:  2              HeII4687     0.1369      0.25     -25     1
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.858      0.28      28    56
# Comp:  1                Halpha      18.45      0.28      28    56
# Comp:  2             [SII]6716      3.053      0.26     -26    33
# Comp:  2             [SII]6731      95.53      0.26     -26    33
# Comp:  2              HeII4687     0.1905      0.26     -26    33
# Comp:  2               HeI5876     0.1533      0.26     -26    33
# Comp:  2          [OIII]5007_d      4.518      0.33     -26    33
# Comp:  2            [OI]6300_d      1.240      0.33     -26    33
# Comp:  2           [NII]6583_d      2.610      0.33     -26    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        11
#  comp.  1:        33        56
#  comp.  2:       -29        13
# chi2/DOF: 1.575; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.849      0.28      33    56
# Comp:  1                Halpha      18.50      0.28      33    56
# Comp:  2             [SII]6716      4.970      0.25     -29    13
# Comp:  2             [SII]6731      90.88      0.25     -29    13
# Comp:  2              HeII4687     0.3664      0.25     -29    13
# Comp:  2               HeI5876     0.2039      0.25     -29    13
# Comp:  2          [OIII]5007_d      4.410      0.31     -29    13
# Comp:  2            [OI]6300_d      1.221      0.31     -29    13
# Comp:  2           [NII]6583_d      2.256      0.31     -29    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31         1
#  comp.  1:        30        55
#  comp.  2:       -20        15
# chi2/DOF: 1.467; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.664      0.28      30    55
# Comp:  1                Halpha      17.97      0.28      30    55
# Comp:  2             [SII]6716      3.898      0.25     -20    15
# Comp:  2             [SII]6731      88.13      0.25     -20    15
# Comp:  2              HeII4687     0.2158      0.25     -20    15
# Comp:  2               HeI5876     0.2149      0.25     -20    15
# Comp:  2          [OIII]5007_d      4.925      0.32     -20    15
# Comp:  2            [OI]6300_d      1.427      0.32     -20    15
# Comp:  2           [NII]6583_d      2.066      0.32     -20    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:        30        57
#  comp.  2:       -31        12
# chi2/DOF: 1.391; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.265      0.28      30    57
# Comp:  1                Halpha      18.60      0.28      30    57
# Comp:  2             [SII]6716      2.991      0.25     -31    12
# Comp:  2             [SII]6731      86.46      0.25     -31    12
# Comp:  2              HeII4687     0.3439      0.25     -31    12
# Comp:  2               HeI5876     0.4289      0.25     -31    12
# Comp:  2          [OIII]5007_d      4.419      0.31     -31    12
# Comp:  2            [OI]6300_d      1.377      0.31     -31    12
# Comp:  2           [NII]6583_d      2.422      0.31     -31    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        55
#  comp.  1:        29        55
#  comp.  2:       -25         1
# chi2/DOF: 1.678; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.006      0.28      29    55
# Comp:  1                Halpha      18.23      0.28      29    55
# Comp:  2             [SII]6716      4.097      0.25     -25     1
# Comp:  2             [SII]6731      89.10      0.25     -25     1
# Comp:  2              HeII4687     0.4494      0.25     -25     1
# Comp:  2               HeI5876     0.1031      0.25     -25     1
# Comp:  2          [OIII]5007_d      4.319      0.31     -25     1
# Comp:  2            [OI]6300_d      1.743      0.31     -25     1
# Comp:  2           [NII]6583_d      1.732      0.31     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:        32        61
#  comp.  2:       -31        16
# chi2/DOF: 1.391; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.235      0.29      32    61
# Comp:  1                Halpha      19.09      0.29      32    61
# Comp:  2             [SII]6716      4.226      0.25     -31    16
# Comp:  2             [SII]6731      88.55      0.25     -31    16
# Comp:  2              HeII4687     0.2105      0.25     -31    16
# Comp:  2               HeI5876     0.1983      0.25     -31    16
# Comp:  2          [OIII]5007_d      4.999      0.32     -31    16
# Comp:  2            [OI]6300_d      1.541      0.32     -31    16
# Comp:  2           [NII]6583_d      1.616      0.32     -31    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:        30        55
#  comp.  2:       -31        11
# chi2/DOF: 1.395; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.613      0.28      30    55
# Comp:  1                Halpha      18.17      0.28      30    55
# Comp:  2             [SII]6716      3.114      0.25     -31    11
# Comp:  2             [SII]6731      86.42      0.25     -31    11
# Comp:  2              HeII4687     0.3200      0.25     -31    11
# Comp:  2               HeI5876     0.3000      0.25     -31    11
# Comp:  2          [OIII]5007_d      5.159      0.31     -31    11
# Comp:  2            [OI]6300_d      1.494      0.31     -31    11
# Comp:  2           [NII]6583_d      2.142      0.31     -31    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42        21
#  comp.  1:        29        54
#  comp.  2:       -20         1
# chi2/DOF: 1.404; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.082      0.28      29    54
# Comp:  1                Halpha      18.35      0.28      29    54
# Comp:  2             [SII]6716      2.790      0.25     -20     1
# Comp:  2             [SII]6731      92.18      0.25     -20     1
# Comp:  2              HeII4687     0.1879      0.25     -20     1
# Comp:  2               HeI5876     0.3370      0.25     -20     1
# Comp:  2          [OIII]5007_d      4.849      0.31     -20     1
# Comp:  2            [OI]6300_d      1.554      0.31     -20     1
# Comp:  2           [NII]6583_d      1.610      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        15
#  comp.  1:        32        57
#  comp.  2:       -20         1
# chi2/DOF: 1.436; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.907      0.28      32    57
# Comp:  1                Halpha      18.23      0.28      32    57
# Comp:  2             [SII]6716      3.453      0.25     -20     1
# Comp:  2             [SII]6731      90.77      0.25     -20     1
# Comp:  2              HeII4687     0.3891      0.25     -20     1
# Comp:  2               HeI5876     0.1430      0.25     -20     1
# Comp:  2          [OIII]5007_d      4.378      0.31     -20     1
# Comp:  2            [OI]6300_d      1.440      0.31     -20     1
# Comp:  2           [NII]6583_d      1.555      0.31     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        46
#  comp.  1:        28        54
#  comp.  2:       -27        29
# chi2/DOF: 1.406; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.749      0.28      28    54
# Comp:  1                Halpha      18.22      0.28      28    54
# Comp:  2             [SII]6716      4.595      0.26     -27    29
# Comp:  2             [SII]6731      94.00      0.26     -27    29
# Comp:  2              HeII4687     0.1573      0.26     -27    29
# Comp:  2               HeI5876     0.1633      0.26     -27    29
# Comp:  2          [OIII]5007_d      4.362      0.33     -27    29
# Comp:  2            [OI]6300_d      1.366      0.33     -27    29
# Comp:  2           [NII]6583_d      2.208      0.33     -27    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37         1
#  comp.  1:        33        61
#  comp.  2:       -20        15
# chi2/DOF: 1.462; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.147      0.29      33    61
# Comp:  1                Halpha      18.69      0.29      33    61
# Comp:  2             [SII]6716      4.383      0.25     -20    15
# Comp:  2             [SII]6731      87.95      0.25     -20    15
# Comp:  2              HeII4687     0.4212      0.25     -20    15
# Comp:  2               HeI5876    0.07719      0.25     -20    15
# Comp:  2          [OIII]5007_d      4.263      0.32     -20    15
# Comp:  2            [OI]6300_d      1.283      0.32     -20    15
# Comp:  2           [NII]6583_d      1.627      0.32     -20    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58        43
#  comp.  1:        30        57
#  comp.  2:       -21         1
# chi2/DOF: 1.531; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.721      0.28      30    57
# Comp:  1                Halpha      18.22      0.28      30    57
# Comp:  2             [SII]6716      4.079      0.25     -21     1
# Comp:  2             [SII]6731      86.65      0.25     -21     1
# Comp:  2              HeII4687     0.3582      0.25     -21     1
# Comp:  2               HeI5876     0.2727      0.25     -21     1
# Comp:  2          [OIII]5007_d      3.956      0.31     -21     1
# Comp:  2            [OI]6300_d      1.309      0.31     -21     1
# Comp:  2           [NII]6583_d      1.511      0.31     -21     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42        69
#  comp.  1:        32        57
#  comp.  2:       -20        10
# chi2/DOF: 1.451; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.927      0.28      32    57
# Comp:  1                Halpha      18.84      0.28      32    57
# Comp:  2             [SII]6716      4.098      0.25     -20    10
# Comp:  2             [SII]6731      87.38      0.25     -20    10
# Comp:  2              HeII4687     0.1848      0.25     -20    10
# Comp:  2               HeI5876     0.1739      0.25     -20    10
# Comp:  2          [OIII]5007_d      4.350      0.31     -20    10
# Comp:  2            [OI]6300_d      1.410      0.31     -20    10
# Comp:  2           [NII]6583_d      1.550      0.31     -20    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        53
#  comp.  1:        28        56
#  comp.  2:       -26        29
# chi2/DOF: 1.404; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.505      0.28      28    56
# Comp:  1                Halpha      18.25      0.28      28    56
# Comp:  2             [SII]6716      3.316      0.26     -26    29
# Comp:  2             [SII]6731      94.34      0.26     -26    29
# Comp:  2              HeII4687     0.3598      0.26     -26    29
# Comp:  2               HeI5876     0.1427      0.26     -26    29
# Comp:  2          [OIII]5007_d      4.682      0.33     -26    29
# Comp:  2            [OI]6300_d      1.697      0.33     -26    29
# Comp:  2           [NII]6583_d      1.806      0.33     -26    29
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.39020959, 0.47767948, 0.87669993, 5.15964752, 0.08798662,
#        0.10591501, 0.47648128, 0.22758935, 0.50625847])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([  4.78658164,  24.92867982,   5.29920808, 124.71570756,
#          0.29994484,   0.27949554,   4.50734631,   1.88154374,
#          2.77656109])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.300722    0.024515
# 1        Halpha  1.566168    0.030011
# 2     [SII]6716  0.332928    0.055080
# 3     [SII]6731  7.835383    0.324160
# 4      HeII4687  0.018844    0.005528
# 5       HeI5876  0.017560    0.006654
# 6  [OIII]5007_d  0.283178    0.029935
# 7    [OI]6300_d  0.118210    0.014299
# 8   [NII]6583_d  0.174440    0.031806
#           Name      Flux  Error_flux
# 0        Hbeta  0.300722    0.024515
# 1       Halpha  1.566168    0.030011
# 2    [SII]6716  0.332928    0.055080
# 3    [SII]6731  7.835383    0.324160
# 4     HeII4687  0.018844    0.005528
# 5      HeI5876  0.017560    0.006654
# 6   [OIII]4959  0.070795    0.029935
# 7   [OIII]5007  0.212384    0.029935
# 8     [OI]6300  0.088657    0.014299
# 9     [OI]6364  0.029552    0.014299
# 10   [NII]6548  0.043610    0.031806
# 11   [NII]6583  0.130830    0.031806

# %%
np.median(flux_rf_rebin)
# Out:
# 0.06282595393620431
