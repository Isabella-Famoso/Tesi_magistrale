# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2221834  2.22292218 2.22366096 ... 3.5409075  3.54164628 3.54238506]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
# chi2/DOF: 0.03041; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
# chi2/DOF: 0.01730; DOF: 1917; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# [1.60894873 1.49467043 1.32753764 ... 0.89494627 0.9144639  0.79256188]
# [1.43510645 1.44908722 1.4539666  ... 0.75034023 0.74694795 0.73977264]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-40.65785727,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:        -8        18
#  comp.  2:       -23        42
# chi2/DOF: 1.216; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.55      0.32      -8    18
# Comp:  1                Halpha      39.41      0.32      -8    18
# Comp:  2             [SII]6716      9.824      0.35     -23    42
# Comp:  2             [SII]6731      8.142      0.35     -23    42
# Comp:  2              HeII4687     0.7756      0.35     -23    42
# Comp:  2               HeI5876      0.000      0.35     -23    42
# Comp:  2          [OIII]5007_d      6.506      0.44     -23    42
# Comp:  2            [OI]6300_d     0.7808      0.44     -23    42
# Comp:  2           [NII]6583_d      7.244      0.44     -23    42
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  33.72; gas flux:     13 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  106.3; gas flux:     54 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  22.33; gas flux:     14 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  19.21; gas flux:     11 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.719; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  11.31; gas flux:      7 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   1.39; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  12.66; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         1         1
#  comp.  1:        -8        20
#  comp.  2:       -31        59
# chi2/DOF: 1.199; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.61      0.33      -8    20
# Comp:  1                Halpha      39.42      0.33      -8    20
# Comp:  2             [SII]6716      10.57      0.37     -31    59
# Comp:  2             [SII]6731      9.068      0.37     -31    59
# Comp:  2              HeII4687     0.4323      0.37     -31    59
# Comp:  2               HeI5876      0.000      0.37     -31    59
# Comp:  2          [OIII]5007_d      6.331      0.47     -31    59
# Comp:  2            [OI]6300_d      1.116      0.47     -31    59
# Comp:  2           [NII]6583_d      7.366      0.47     -31    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:       -12        25
#  comp.  2:       -30        59
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.85      0.33     -12    25
# Comp:  1                Halpha      40.48      0.33     -12    25
# Comp:  2             [SII]6716      11.19      0.37     -30    59
# Comp:  2             [SII]6731      9.247      0.37     -30    59
# Comp:  2              HeII4687     0.8968      0.37     -30    59
# Comp:  2               HeI5876     0.2503      0.37     -30    59
# Comp:  2          [OIII]5007_d      7.030      0.47     -30    59
# Comp:  2            [OI]6300_d     0.6032      0.47     -30    59
# Comp:  2           [NII]6583_d      7.898      0.47     -30    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        33
#  comp.  1:        -7        11
#  comp.  2:       -17        29
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.28      0.32      -7    11
# Comp:  1                Halpha      39.98      0.32      -7    11
# Comp:  2             [SII]6716      9.307      0.33     -17    29
# Comp:  2             [SII]6731      7.673      0.33     -17    29
# Comp:  2              HeII4687     0.9476      0.33     -17    29
# Comp:  2               HeI5876      0.000      0.33     -17    29
# Comp:  2          [OIII]5007_d      5.960      0.42     -17    29
# Comp:  2            [OI]6300_d     0.5361      0.42     -17    29
# Comp:  2           [NII]6583_d      7.087      0.42     -17    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         5
#  comp.  1:       -11        28
#  comp.  2:       -19        27
# chi2/DOF: 1.184; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.83      0.33     -11    28
# Comp:  1                Halpha      41.08      0.33     -11    28
# Comp:  2             [SII]6716      9.503      0.33     -19    27
# Comp:  2             [SII]6731      7.959      0.33     -19    27
# Comp:  2              HeII4687      1.019      0.33     -19    27
# Comp:  2               HeI5876     0.2457      0.33     -19    27
# Comp:  2          [OIII]5007_d      5.779      0.42     -19    27
# Comp:  2            [OI]6300_d     0.5866      0.42     -19    27
# Comp:  2           [NII]6583_d      7.815      0.42     -19    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -12        25
#  comp.  2:       -20        30
# chi2/DOF: 1.176; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.43      0.33     -12    25
# Comp:  1                Halpha      40.96      0.33     -12    25
# Comp:  2             [SII]6716      9.900      0.33     -20    30
# Comp:  2             [SII]6731      7.698      0.33     -20    30
# Comp:  2              HeII4687     0.8329      0.33     -20    30
# Comp:  2               HeI5876     0.1696      0.33     -20    30
# Comp:  2          [OIII]5007_d      6.050      0.42     -20    30
# Comp:  2            [OI]6300_d      1.026      0.42     -20    30
# Comp:  2           [NII]6583_d      6.763      0.42     -20    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -10        28
#  comp.  2:       -17        18
# chi2/DOF: 1.178; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.39      0.33     -10    28
# Comp:  1                Halpha      41.71      0.33     -10    28
# Comp:  2             [SII]6716      9.227      0.33     -17    18
# Comp:  2             [SII]6731      6.895      0.33     -17    18
# Comp:  2              HeII4687     0.4868      0.33     -17    18
# Comp:  2               HeI5876      0.000      0.33     -17    18
# Comp:  2          [OIII]5007_d      5.553      0.41     -17    18
# Comp:  2            [OI]6300_d      1.060      0.41     -17    18
# Comp:  2           [NII]6583_d      6.925      0.41     -17    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        54
#  comp.  1:        -8        15
#  comp.  2:       -22        45
# chi2/DOF: 1.202; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.73      0.32      -8    15
# Comp:  1                Halpha      39.87      0.32      -8    15
# Comp:  2             [SII]6716      10.24      0.35     -22    45
# Comp:  2             [SII]6731      9.417      0.35     -22    45
# Comp:  2              HeII4687      1.213      0.35     -22    45
# Comp:  2               HeI5876      0.000      0.35     -22    45
# Comp:  2          [OIII]5007_d      6.612      0.44     -22    45
# Comp:  2            [OI]6300_d     0.9788      0.44     -22    45
# Comp:  2           [NII]6583_d      7.498      0.44     -22    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:        -9        24
#  comp.  2:       -27        48
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.56      0.33      -9    24
# Comp:  1                Halpha      39.42      0.33      -9    24
# Comp:  2             [SII]6716      9.383      0.35     -27    48
# Comp:  2             [SII]6731      9.121      0.35     -27    48
# Comp:  2              HeII4687      1.093      0.35     -27    48
# Comp:  2               HeI5876      0.000      0.35     -27    48
# Comp:  2          [OIII]5007_d      6.463      0.45     -27    48
# Comp:  2            [OI]6300_d      1.006      0.45     -27    48
# Comp:  2           [NII]6583_d      7.947      0.45     -27    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        42
#  comp.  1:       -11        23
#  comp.  2:       -17        27
# chi2/DOF: 1.179; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.50      0.33     -11    23
# Comp:  1                Halpha      40.93      0.33     -11    23
# Comp:  2             [SII]6716      8.855      0.33     -17    27
# Comp:  2             [SII]6731      6.927      0.33     -17    27
# Comp:  2              HeII4687     0.6369      0.33     -17    27
# Comp:  2               HeI5876    0.05366      0.33     -17    27
# Comp:  2          [OIII]5007_d      5.938      0.42     -17    27
# Comp:  2            [OI]6300_d     0.5230      0.42     -17    27
# Comp:  2           [NII]6583_d      6.268      0.42     -17    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:        -8        10
#  comp.  2:       -18        26
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.37      0.32      -8    10
# Comp:  1                Halpha      39.92      0.32      -8    10
# Comp:  2             [SII]6716      9.028      0.33     -18    26
# Comp:  2             [SII]6731      7.923      0.33     -18    26
# Comp:  2              HeII4687     0.4638      0.33     -18    26
# Comp:  2               HeI5876     0.2012      0.33     -18    26
# Comp:  2          [OIII]5007_d      6.366      0.42     -18    26
# Comp:  2            [OI]6300_d      1.059      0.42     -18    26
# Comp:  2           [NII]6583_d      6.127      0.42     -18    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:        -8        26
#  comp.  2:       -18        26
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.17      0.33      -8    26
# Comp:  1                Halpha      39.51      0.33      -8    26
# Comp:  2             [SII]6716      9.585      0.33     -18    26
# Comp:  2             [SII]6731      7.937      0.33     -18    26
# Comp:  2              HeII4687     0.9866      0.33     -18    26
# Comp:  2               HeI5876    0.08235      0.33     -18    26
# Comp:  2          [OIII]5007_d      6.251      0.42     -18    26
# Comp:  2            [OI]6300_d     0.6702      0.42     -18    26
# Comp:  2           [NII]6583_d      7.364      0.42     -18    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        34
#  comp.  1:        -5         9
#  comp.  2:       -18        30
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.48      0.32      -5     9
# Comp:  1                Halpha      37.99      0.32      -5     9
# Comp:  2             [SII]6716      10.04      0.33     -18    30
# Comp:  2             [SII]6731      7.738      0.33     -18    30
# Comp:  2              HeII4687     0.5988      0.33     -18    30
# Comp:  2               HeI5876      0.000      0.33     -18    30
# Comp:  2          [OIII]5007_d      6.449      0.42     -18    30
# Comp:  2            [OI]6300_d     0.8466      0.42     -18    30
# Comp:  2           [NII]6583_d      6.081      0.42     -18    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        48
#  comp.  1:        -8        10
#  comp.  2:       -27        52
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.75      0.32      -8    10
# Comp:  1                Halpha      40.09      0.32      -8    10
# Comp:  2             [SII]6716      10.43      0.36     -27    52
# Comp:  2             [SII]6731      9.790      0.36     -27    52
# Comp:  2              HeII4687     0.5545      0.36     -27    52
# Comp:  2               HeI5876    0.01429      0.36     -27    52
# Comp:  2          [OIII]5007_d      6.548      0.45     -27    52
# Comp:  2            [OI]6300_d     0.9284      0.45     -27    52
# Comp:  2           [NII]6583_d      7.670      0.45     -27    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:       -11        25
#  comp.  2:       -23        33
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.63      0.33     -11    25
# Comp:  1                Halpha      40.99      0.33     -11    25
# Comp:  2             [SII]6716      10.04      0.34     -23    33
# Comp:  2             [SII]6731      8.020      0.34     -23    33
# Comp:  2              HeII4687      1.166      0.34     -23    33
# Comp:  2               HeI5876      0.000      0.34     -23    33
# Comp:  2          [OIII]5007_d      6.265      0.43     -23    33
# Comp:  2            [OI]6300_d     0.8419      0.43     -23    33
# Comp:  2           [NII]6583_d      6.985      0.43     -23    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -11        22
#  comp.  2:       -26        39
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.66      0.33     -11    22
# Comp:  1                Halpha      40.81      0.33     -11    22
# Comp:  2             [SII]6716      9.824      0.34     -26    39
# Comp:  2             [SII]6731      9.101      0.34     -26    39
# Comp:  2              HeII4687      1.106      0.34     -26    39
# Comp:  2               HeI5876      0.000      0.34     -26    39
# Comp:  2          [OIII]5007_d      6.392      0.43     -26    39
# Comp:  2            [OI]6300_d     0.4778      0.43     -26    39
# Comp:  2           [NII]6583_d      7.680      0.43     -26    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11         1
#  comp.  1:        -9         8
#  comp.  2:       -24        36
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.01      0.32      -9     8
# Comp:  1                Halpha      39.21      0.32      -9     8
# Comp:  2             [SII]6716      9.419      0.34     -24    36
# Comp:  2             [SII]6731      6.901      0.34     -24    36
# Comp:  2              HeII4687     0.8165      0.34     -24    36
# Comp:  2               HeI5876     0.1119      0.34     -24    36
# Comp:  2          [OIII]5007_d      5.871      0.43     -24    36
# Comp:  2            [OI]6300_d     0.6538      0.43     -24    36
# Comp:  2           [NII]6583_d      6.477      0.43     -24    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24         9
#  comp.  1:       -11        28
#  comp.  2:       -22        34
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.51      0.33     -11    28
# Comp:  1                Halpha      41.19      0.33     -11    28
# Comp:  2             [SII]6716      9.148      0.34     -22    34
# Comp:  2             [SII]6731      6.848      0.34     -22    34
# Comp:  2              HeII4687     0.6147      0.34     -22    34
# Comp:  2               HeI5876    0.01873      0.34     -22    34
# Comp:  2          [OIII]5007_d      5.940      0.43     -22    34
# Comp:  2            [OI]6300_d      1.116      0.43     -22    34
# Comp:  2           [NII]6583_d      7.076      0.43     -22    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        78
#  comp.  1:        -8        18
#  comp.  2:       -29        63
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.77      0.32      -8    18
# Comp:  1                Halpha      39.60      0.32      -8    18
# Comp:  2             [SII]6716      11.37      0.37     -29    63
# Comp:  2             [SII]6731      9.183      0.37     -29    63
# Comp:  2              HeII4687     0.7818      0.37     -29    63
# Comp:  2               HeI5876    0.05269      0.37     -29    63
# Comp:  2          [OIII]5007_d      6.435      0.47     -29    63
# Comp:  2            [OI]6300_d     0.6528      0.47     -29    63
# Comp:  2           [NII]6583_d      7.908      0.47     -29    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:        -9         6
#  comp.  2:       -21        40
# chi2/DOF: 1.201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.77      0.32      -9     6
# Comp:  1                Halpha      39.55      0.32      -9     6
# Comp:  2             [SII]6716      9.744      0.34     -21    40
# Comp:  2             [SII]6731      8.239      0.34     -21    40
# Comp:  2              HeII4687     0.9200      0.34     -21    40
# Comp:  2               HeI5876    0.08944      0.34     -21    40
# Comp:  2          [OIII]5007_d      6.285      0.44     -21    40
# Comp:  2            [OI]6300_d     0.3050      0.44     -21    40
# Comp:  2           [NII]6583_d      6.567      0.44     -21    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:       -10        29
#  comp.  2:       -26        51
# chi2/DOF: 1.182; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.63      0.33     -10    29
# Comp:  1                Halpha      40.98      0.33     -10    29
# Comp:  2             [SII]6716      9.575      0.36     -26    51
# Comp:  2             [SII]6731      9.701      0.36     -26    51
# Comp:  2              HeII4687     0.9495      0.36     -26    51
# Comp:  2               HeI5876    0.07045      0.36     -26    51
# Comp:  2          [OIII]5007_d      6.937      0.45     -26    51
# Comp:  2            [OI]6300_d     0.9131      0.45     -26    51
# Comp:  2           [NII]6583_d      7.937      0.45     -26    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        14
#  comp.  1:        -7        12
#  comp.  2:       -28        51
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.80      0.32      -7    12
# Comp:  1                Halpha      39.93      0.32      -7    12
# Comp:  2             [SII]6716      10.86      0.36     -28    51
# Comp:  2             [SII]6731      9.516      0.36     -28    51
# Comp:  2              HeII4687      1.030      0.36     -28    51
# Comp:  2               HeI5876     0.1787      0.36     -28    51
# Comp:  2          [OIII]5007_d      6.973      0.45     -28    51
# Comp:  2            [OI]6300_d      1.061      0.45     -28    51
# Comp:  2           [NII]6583_d      6.971      0.45     -28    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        25
#  comp.  1:       -11        26
#  comp.  2:       -19        19
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.80      0.33     -11    26
# Comp:  1                Halpha      41.04      0.33     -11    26
# Comp:  2             [SII]6716      8.634      0.33     -19    19
# Comp:  2             [SII]6731      7.519      0.33     -19    19
# Comp:  2              HeII4687     0.8484      0.33     -19    19
# Comp:  2               HeI5876    0.02925      0.33     -19    19
# Comp:  2          [OIII]5007_d      5.803      0.41     -19    19
# Comp:  2            [OI]6300_d     0.9453      0.41     -19    19
# Comp:  2           [NII]6583_d      6.680      0.41     -19    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:        -8         7
#  comp.  2:       -19        21
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.89      0.32      -8     7
# Comp:  1                Halpha      39.48      0.32      -8     7
# Comp:  2             [SII]6716      9.547      0.33     -19    21
# Comp:  2             [SII]6731      7.867      0.33     -19    21
# Comp:  2              HeII4687     0.7840      0.33     -19    21
# Comp:  2               HeI5876      0.000      0.33     -19    21
# Comp:  2          [OIII]5007_d      6.108      0.41     -19    21
# Comp:  2            [OI]6300_d     0.3738      0.41     -19    21
# Comp:  2           [NII]6583_d      6.186      0.41     -19    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:        -4        14
#  comp.  2:       -25        49
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.62      0.32      -4    14
# Comp:  1                Halpha      38.29      0.32      -4    14
# Comp:  2             [SII]6716      9.605      0.36     -25    49
# Comp:  2             [SII]6731      8.140      0.36     -25    49
# Comp:  2              HeII4687      1.093      0.36     -25    49
# Comp:  2               HeI5876      0.000      0.36     -25    49
# Comp:  2          [OIII]5007_d      7.285      0.45     -25    49
# Comp:  2            [OI]6300_d     0.4191      0.45     -25    49
# Comp:  2           [NII]6583_d      7.675      0.45     -25    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        61
#  comp.  1:       -11        25
#  comp.  2:       -16        15
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.75      0.33     -11    25
# Comp:  1                Halpha      40.42      0.33     -11    25
# Comp:  2             [SII]6716      9.213      0.32     -16    15
# Comp:  2             [SII]6731      7.765      0.32     -16    15
# Comp:  2              HeII4687     0.9773      0.32     -16    15
# Comp:  2               HeI5876   0.007155      0.32     -16    15
# Comp:  2          [OIII]5007_d      5.697      0.41     -16    15
# Comp:  2            [OI]6300_d     0.5069      0.41     -16    15
# Comp:  2           [NII]6583_d      6.686      0.41     -16    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       126       255
#  comp.  1:        -5         1
#  comp.  2:       -22        36
# chi2/DOF: 1.193; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.30      0.32      -5     1
# Comp:  1                Halpha      38.09      0.32      -5     1
# Comp:  2             [SII]6716      9.398      0.34     -22    36
# Comp:  2             [SII]6731      7.077      0.34     -22    36
# Comp:  2              HeII4687     0.6614      0.34     -22    36
# Comp:  2               HeI5876      0.000      0.34     -22    36
# Comp:  2          [OIII]5007_d      6.288      0.43     -22    36
# Comp:  2            [OI]6300_d     0.9814      0.43     -22    36
# Comp:  2           [NII]6583_d      7.085      0.43     -22    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         1
#  comp.  1:        -6         2
#  comp.  2:       -20        27
# chi2/DOF: 1.190; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.62      0.32      -6     2
# Comp:  1                Halpha      38.40      0.32      -6     2
# Comp:  2             [SII]6716      9.847      0.33     -20    27
# Comp:  2             [SII]6731      7.009      0.33     -20    27
# Comp:  2              HeII4687      1.015      0.33     -20    27
# Comp:  2               HeI5876      0.000      0.33     -20    27
# Comp:  2          [OIII]5007_d      5.856      0.42     -20    27
# Comp:  2            [OI]6300_d      1.138      0.42     -20    27
# Comp:  2           [NII]6583_d      6.763      0.42     -20    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        52
#  comp.  1:       -10        27
#  comp.  2:       -23        36
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.68      0.33     -10    27
# Comp:  1                Halpha      41.27      0.33     -10    27
# Comp:  2             [SII]6716      9.509      0.34     -23    36
# Comp:  2             [SII]6731      6.868      0.34     -23    36
# Comp:  2              HeII4687     0.4113      0.34     -23    36
# Comp:  2               HeI5876    0.09512      0.34     -23    36
# Comp:  2          [OIII]5007_d      6.210      0.43     -23    36
# Comp:  2            [OI]6300_d     0.8895      0.43     -23    36
# Comp:  2           [NII]6583_d      7.721      0.43     -23    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:       -10        26
#  comp.  2:       -22        53
# chi2/DOF: 1.183; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.54      0.33     -10    26
# Comp:  1                Halpha      41.41      0.33     -10    26
# Comp:  2             [SII]6716      10.01      0.36     -22    53
# Comp:  2             [SII]6731      7.417      0.36     -22    53
# Comp:  2              HeII4687     0.5636      0.36     -22    53
# Comp:  2               HeI5876     0.2625      0.36     -22    53
# Comp:  2          [OIII]5007_d      6.868      0.46     -22    53
# Comp:  2            [OI]6300_d     0.5720      0.46     -22    53
# Comp:  2           [NII]6583_d      7.356      0.46     -22    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        49
#  comp.  1:       -11        28
#  comp.  2:       -32        56
# chi2/DOF: 1.178; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.51      0.33     -11    28
# Comp:  1                Halpha      41.25      0.33     -11    28
# Comp:  2             [SII]6716      10.92      0.37     -32    56
# Comp:  2             [SII]6731      9.830      0.37     -32    56
# Comp:  2              HeII4687     0.9633      0.37     -32    56
# Comp:  2               HeI5876      0.000      0.37     -32    56
# Comp:  2          [OIII]5007_d      7.102      0.46     -32    56
# Comp:  2            [OI]6300_d     0.7046      0.46     -32    56
# Comp:  2           [NII]6583_d      7.966      0.46     -32    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        65
#  comp.  1:        -9        26
#  comp.  2:       -20        26
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.30      0.33      -9    26
# Comp:  1                Halpha      39.63      0.33      -9    26
# Comp:  2             [SII]6716      9.636      0.33     -20    26
# Comp:  2             [SII]6731      6.736      0.33     -20    26
# Comp:  2              HeII4687     0.5034      0.33     -20    26
# Comp:  2               HeI5876      0.000      0.33     -20    26
# Comp:  2          [OIII]5007_d      5.941      0.42     -20    26
# Comp:  2            [OI]6300_d     0.3635      0.42     -20    26
# Comp:  2           [NII]6583_d      6.301      0.42     -20    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        44
#  comp.  1:        -8        24
#  comp.  2:       -28        58
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.45      0.33      -8    24
# Comp:  1                Halpha      39.18      0.33      -8    24
# Comp:  2             [SII]6716      9.868      0.37     -28    58
# Comp:  2             [SII]6731      8.855      0.37     -28    58
# Comp:  2              HeII4687      1.043      0.37     -28    58
# Comp:  2               HeI5876      0.000      0.37     -28    58
# Comp:  2          [OIII]5007_d      7.081      0.46     -28    58
# Comp:  2            [OI]6300_d     0.3763      0.46     -28    58
# Comp:  2           [NII]6583_d      6.905      0.46     -28    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        87
#  comp.  1:       -10        28
#  comp.  2:       -17        35
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.94      0.33     -10    28
# Comp:  1                Halpha      41.09      0.33     -10    28
# Comp:  2             [SII]6716      9.928      0.34     -17    35
# Comp:  2             [SII]6731      7.302      0.34     -17    35
# Comp:  2              HeII4687     0.5152      0.34     -17    35
# Comp:  2               HeI5876      0.000      0.34     -17    35
# Comp:  2          [OIII]5007_d      5.879      0.43     -17    35
# Comp:  2            [OI]6300_d     0.6107      0.43     -17    35
# Comp:  2           [NII]6583_d      8.091      0.43     -17    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        44
#  comp.  1:        -7        20
#  comp.  2:       -14        39
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.79      0.33      -7    20
# Comp:  1                Halpha      39.60      0.33      -7    20
# Comp:  2             [SII]6716      10.07      0.34     -14    39
# Comp:  2             [SII]6731      7.267      0.34     -14    39
# Comp:  2              HeII4687     0.8994      0.34     -14    39
# Comp:  2               HeI5876    0.05326      0.34     -14    39
# Comp:  2          [OIII]5007_d      6.361      0.43     -14    39
# Comp:  2            [OI]6300_d      1.108      0.43     -14    39
# Comp:  2           [NII]6583_d      7.893      0.43     -14    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        67
#  comp.  1:        -5         2
#  comp.  2:       -25        51
# chi2/DOF: 1.182; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.84      0.32      -5     2
# Comp:  1                Halpha      38.69      0.32      -5     2
# Comp:  2             [SII]6716      10.33      0.36     -25    51
# Comp:  2             [SII]6731      9.700      0.36     -25    51
# Comp:  2              HeII4687     0.4370      0.36     -25    51
# Comp:  2               HeI5876     0.1436      0.36     -25    51
# Comp:  2          [OIII]5007_d      6.469      0.45     -25    51
# Comp:  2            [OI]6300_d      1.013      0.45     -25    51
# Comp:  2           [NII]6583_d      7.762      0.45     -25    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:        -6         1
#  comp.  2:       -26        61
# chi2/DOF: 1.174; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.19      0.32      -6     1
# Comp:  1                Halpha      38.04      0.32      -6     1
# Comp:  2             [SII]6716      11.30      0.37     -26    61
# Comp:  2             [SII]6731      8.894      0.37     -26    61
# Comp:  2              HeII4687     0.4079      0.37     -26    61
# Comp:  2               HeI5876      0.000      0.37     -26    61
# Comp:  2          [OIII]5007_d      7.027      0.47     -26    61
# Comp:  2            [OI]6300_d     0.7664      0.47     -26    61
# Comp:  2           [NII]6583_d      7.778      0.47     -26    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        51
#  comp.  1:        -6         1
#  comp.  2:       -28        59
# chi2/DOF: 1.182; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.86      0.32      -6     1
# Comp:  1                Halpha      38.48      0.32      -6     1
# Comp:  2             [SII]6716      9.990      0.37     -28    59
# Comp:  2             [SII]6731      8.886      0.37     -28    59
# Comp:  2              HeII4687     0.4555      0.37     -28    59
# Comp:  2               HeI5876    0.01005      0.37     -28    59
# Comp:  2          [OIII]5007_d      6.713      0.47     -28    59
# Comp:  2            [OI]6300_d      1.099      0.47     -28    59
# Comp:  2           [NII]6583_d      7.313      0.47     -28    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:        -5         7
#  comp.  2:       -30        64
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.38      0.32      -5     7
# Comp:  1                Halpha      38.37      0.32      -5     7
# Comp:  2             [SII]6716      10.20      0.38     -30    64
# Comp:  2             [SII]6731      9.317      0.38     -30    64
# Comp:  2              HeII4687     0.6601      0.38     -30    64
# Comp:  2               HeI5876      0.000      0.38     -30    64
# Comp:  2          [OIII]5007_d      7.164      0.48     -30    64
# Comp:  2            [OI]6300_d     0.6967      0.48     -30    64
# Comp:  2           [NII]6583_d      7.360      0.48     -30    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:        -6         1
#  comp.  2:       -16        17
# chi2/DOF: 1.177; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.19      0.32      -6     1
# Comp:  1                Halpha      37.96      0.32      -6     1
# Comp:  2             [SII]6716      8.700      0.32     -16    17
# Comp:  2             [SII]6731      7.650      0.32     -16    17
# Comp:  2              HeII4687     0.4579      0.32     -16    17
# Comp:  2               HeI5876      0.000      0.32     -16    17
# Comp:  2          [OIII]5007_d      6.038      0.41     -16    17
# Comp:  2            [OI]6300_d     0.9366      0.41     -16    17
# Comp:  2           [NII]6583_d      7.395      0.41     -16    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        17
#  comp.  1:        -8        18
#  comp.  2:       -16        36
# chi2/DOF: 1.203; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.47      0.32      -8    18
# Comp:  1                Halpha      39.61      0.32      -8    18
# Comp:  2             [SII]6716      9.103      0.34     -16    36
# Comp:  2             [SII]6731      7.055      0.34     -16    36
# Comp:  2              HeII4687     0.7173      0.34     -16    36
# Comp:  2               HeI5876      0.000      0.34     -16    36
# Comp:  2          [OIII]5007_d      6.262      0.43     -16    36
# Comp:  2            [OI]6300_d     0.6498      0.43     -16    36
# Comp:  2           [NII]6583_d      6.717      0.43     -16    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        64
#  comp.  1:        -8        14
#  comp.  2:       -21        42
# chi2/DOF: 1.195; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.31      0.32      -8    14
# Comp:  1                Halpha      40.26      0.32      -8    14
# Comp:  2             [SII]6716      9.626      0.35     -21    42
# Comp:  2             [SII]6731      7.232      0.35     -21    42
# Comp:  2              HeII4687     0.7510      0.35     -21    42
# Comp:  2               HeI5876      0.000      0.35     -21    42
# Comp:  2          [OIII]5007_d      6.211      0.44     -21    42
# Comp:  2            [OI]6300_d     0.3120      0.44     -21    42
# Comp:  2           [NII]6583_d      7.063      0.44     -21    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        -7        24
#  comp.  2:       -25        44
# chi2/DOF: 1.198; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.65      0.33      -7    24
# Comp:  1                Halpha      39.89      0.33      -7    24
# Comp:  2             [SII]6716      10.02      0.35     -25    44
# Comp:  2             [SII]6731      9.398      0.35     -25    44
# Comp:  2              HeII4687     0.7681      0.35     -25    44
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.10      0.32      -8     9
# Comp:  1                Halpha      39.83      0.32      -8     9
# Comp:  2             [SII]6716      8.906      0.34     -19    32
# Comp:  2             [SII]6731      7.004      0.34     -19    32
# Comp:  2              HeII4687     0.8583      0.34     -19    32
# Comp:  2               HeI5876      0.000      0.34     -19    32
# Comp:  2          [OIII]5007_d      6.317      0.42     -19    32
# Comp:  2            [OI]6300_d     0.4350      0.42     -19    32
# Comp:  2           [NII]6583_d      6.088      0.42     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -11        22
#  comp.  2:       -24        50
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.37      0.33     -11    22
# Comp:  1                Halpha      41.25      0.33     -11    22
# Comp:  2             [SII]6716      10.86      0.36     -24    50
# Comp:  2             [SII]6731      9.578      0.36     -24    50
# Comp:  2              HeII4687     0.7344      0.36     -24    50
# Comp:  2               HeI5876      0.000      0.36     -24    50
# Comp:  2          [OIII]5007_d      7.164      0.45     -24    50
# Comp:  2            [OI]6300_d      1.072      0.45     -24    50
# Comp:  2           [NII]6583_d      7.970      0.45     -24    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
#  comp.  1:        -5         1
#  comp.  2:       -17         1
# chi2/DOF: 1.165; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.25      0.32      -5     1
# Comp:  1                Halpha      38.04      0.32      -5     1
# Comp:  2             [SII]6716      9.188      0.32     -17     1
# Comp:  2             [SII]6731      7.684      0.32     -17     1
# Comp:  2              HeII4687     0.9547      0.32     -17     1
# Comp:  2               HeI5876    0.05356      0.32     -17     1
# Comp:  2          [OIII]5007_d      5.540      0.40     -17     1
# Comp:  2            [OI]6300_d     0.8969      0.40     -17     1
# Comp:  2           [NII]6583_d      6.542      0.40     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10         1
#  comp.  1:        -8        10
#  comp.  2:       -16         1
# chi2/DOF: 1.185; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.62      0.32      -8    10
# Comp:  1                Halpha      39.45      0.32      -8    10
# Comp:  2             [SII]6716      9.139      0.32     -16     1
# Comp:  2             [SII]6731      7.738      0.32     -16     1
# Comp:  2              HeII4687     0.9072      0.32     -16     1
# Comp:  2               HeI5876      0.000      0.32     -16     1
# Comp:  2          [OIII]5007_d      5.838      0.40     -16     1
# Comp:  2            [OI]6300_d     0.8306      0.40     -16     1
# Comp:  2           [NII]6583_d      6.693      0.40     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        56
#  comp.  1:       -10        26
#  comp.  2:       -27        51
# chi2/DOF: 1.180; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.48      0.33     -10    26
# Comp:  1                Halpha      41.48      0.33     -10    26
# Comp:  2             [SII]6716      10.73      0.36     -27    51
# Comp:  2             [SII]6731      9.336      0.36     -27    51
# Comp:  2              HeII4687      1.229      0.36     -27    51
# Comp:  2               HeI5876     0.1231      0.36     -27    51
# Comp:  2          [OIII]5007_d      6.344      0.45     -27    51
# Comp:  2            [OI]6300_d     0.4785      0.45     -27    51
# Comp:  2           [NII]6583_d      7.484      0.45     -27    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        46
#  comp.  1:       -12        30
#  comp.  2:       -20        39
# chi2/DOF: 1.181; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.13      0.33     -12    30
# Comp:  1                Halpha      41.33      0.33     -12    30
# Comp:  2             [SII]6716      9.502      0.34     -20    39
# Comp:  2             [SII]6731      8.403      0.34     -20    39
# Comp:  2              HeII4687     0.5208      0.34     -20    39
# Comp:  2               HeI5876    0.05159      0.34     -20    39
# Comp:  2          [OIII]5007_d      6.824      0.43     -20    39
# Comp:  2            [OI]6300_d     0.7818      0.43     -20    39
# Comp:  2           [NII]6583_d      7.808      0.43     -20    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6         1
#  comp.  1:        -8        15
#  comp.  2:       -15        29
# chi2/DOF: 1.200; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.69      0.32      -8    15
# Comp:  1                Halpha      39.47      0.32      -8    15
# Comp:  2             [SII]6716      9.843      0.33     -15    29
# Comp:  2             [SII]6731      7.034      0.33     -15    29
# Comp:  2              HeII4687     0.5872      0.33     -15    29
# Comp:  2               HeI5876      0.000      0.33     -15    29
# Comp:  2          [OIII]5007_d      6.579      0.42     -15    29
# Comp:  2            [OI]6300_d      1.020      0.42     -15    29
# Comp:  2           [NII]6583_d      6.931      0.42     -15    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        31
#  comp.  1:        -7        28
#  comp.  2:       -33        54
# chi2/DOF: 1.184; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.58      0.33      -7    28
# Comp:  1                Halpha      39.54      0.33      -7    28
# Comp:  2             [SII]6716      9.690      0.36     -33    54
# Comp:  2             [SII]6731      8.873      0.36     -33    54
# Comp:  2              HeII4687      1.287      0.36     -33    54
# Comp:  2               HeI5876    0.02254      0.36     -33    54
# Comp:  2          [OIII]5007_d      6.771      0.46     -33    54
# Comp:  2            [OI]6300_d     0.5282      0.46     -33    54
# Comp:  2           [NII]6583_d      6.293      0.46     -33    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        75
#  comp.  1:       -11        23
#  comp.  2:       -19        43
# chi2/DOF: 1.184; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.57      0.33     -11    23
# Comp:  1                Halpha      41.43      0.33     -11    23
# Comp:  2             [SII]6716      10.53      0.35     -19    43
# Comp:  2             [SII]6731      8.468      0.35     -19    43
# Comp:  2              HeII4687     0.6751      0.35     -19    43
# Comp:  2               HeI5876      0.000      0.35     -19    43
# Comp:  2          [OIII]5007_d      6.516      0.44     -19    43
# Comp:  2            [OI]6300_d     0.7660      0.44     -19    43
# Comp:  2           [NII]6583_d      8.240      0.44     -19    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        55
#  comp.  1:       -10        24
#  comp.  2:       -19        36
# chi2/DOF: 1.188; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.28      0.33     -10    24
# Comp:  1                Halpha      41.58      0.33     -10    24
# Comp:  2             [SII]6716      9.815      0.34     -19    36
# Comp:  2             [SII]6731      7.357      0.34     -19    36
# Comp:  2              HeII4687     0.6909      0.34     -19    36
# Comp:  2               HeI5876      0.000      0.34     -19    36
# Comp:  2          [OIII]5007_d      6.244      0.43     -19    36
# Comp:  2            [OI]6300_d     0.7986      0.43     -19    36
# Comp:  2           [NII]6583_d      6.297      0.43     -19    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        88
#  comp.  1:        -8        13
#  comp.  2:       -12        29
# chi2/DOF: 1.189; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.20      0.32      -8    13
# Comp:  1                Halpha      39.09      0.32      -8    13
# Comp:  2             [SII]6716      9.734      0.33     -12    29
# Comp:  2             [SII]6731      7.847      0.33     -12    29
# Comp:  2              HeII4687      1.085      0.33     -12    29
# Comp:  2               HeI5876    0.09088      0.33     -12    29
# Comp:  2          [OIII]5007_d      6.650      0.42     -12    29
# Comp:  2            [OI]6300_d     0.5601      0.42     -12    29
# Comp:  2           [NII]6583_d      6.341      0.42     -12    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        52
#  comp.  1:        -8        23
#  comp.  2:       -21        45
# chi2/DOF: 1.201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.93      0.33      -8    23
# Comp:  1                Halpha      39.27      0.33      -8    23
# Comp:  2             [SII]6716      9.830      0.35     -21    45
# Comp:  2             [SII]6731      7.229      0.35     -21    45
# Comp:  2              HeII4687     0.8654      0.35     -21    45
# Comp:  2               HeI5876      0.000      0.35     -21    45
# Comp:  2          [OIII]5007_d      6.377      0.44     -21    45
# Comp:  2            [OI]6300_d     0.4943      0.44     -21    45
# Comp:  2           [NII]6583_d      7.827      0.44     -21    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        63
#  comp.  1:        -6         1
#  comp.  2:       -25        51
# chi2/DOF: 1.186; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.86      0.32      -6     1
# Comp:  1                Halpha      38.52      0.32      -6     1
# Comp:  2             [SII]6716      10.36      0.36     -25    51
# Comp:  2             [SII]6731      8.700      0.36     -25    51
# Comp:  2              HeII4687     0.6024      0.36     -25    51
# Comp:  2               HeI5876     0.1220      0.36     -25    51
# Comp:  2          [OIII]5007_d      7.044      0.45     -25    51
# Comp:  2            [OI]6300_d     0.7821      0.45     -25    51
# Comp:  2           [NII]6583_d      7.354      0.45     -25    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:       -11        21
#  comp.  2:       -26        50
# chi2/DOF: 1.183; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.38      0.33     -11    21
# Comp:  1                Halpha      40.69      0.33     -11    21
# Comp:  2             [SII]6716      9.690      0.36     -26    50
# Comp:  2             [SII]6731      9.622      0.36     -26    50
# Comp:  2              HeII4687     0.5729      0.36     -26    50
# Comp:  2               HeI5876      0.000      0.36     -26    50
# Comp:  2          [OIII]5007_d      6.658      0.45     -26    50
# Comp:  2            [OI]6300_d     0.6237      0.45     -26    50
# Comp:  2           [NII]6583_d      7.040      0.45     -26    50
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.55796885, 1.54791852, 0.77371877, 1.2355896 , 0.27273789,
#        0.08744426, 0.40489158, 0.3246162 , 0.90597031])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([12.72868027, 53.94524222, 13.762555  , 11.4304344 ,  0.75799623,
#         0.        ,  6.79384938,  1.02607691,  9.9470784 ])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_4_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.619258    0.027146
# 1        Halpha  2.624469    0.075307
# 2     [SII]6716  0.669557    0.037642
# 3     [SII]6731  0.556098    0.060112
# 4      HeII4687  0.036877    0.013269
# 5       HeI5876  0.000000    0.004254
# 6  [OIII]5007_d  0.330525    0.019698
# 7    [OI]6300_d  0.049919    0.015793
# 8   [NII]6583_d  0.483931    0.044076
#           Name      Flux  Error_flux
# 0        Hbeta  0.619258    0.027146
# 1       Halpha  2.624469    0.075307
# 2    [SII]6716  0.669557    0.037642
# 3    [SII]6731  0.556098    0.060112
# 4     HeII4687  0.036877    0.013269
# 5      HeI5876  0.000000    0.004254
# 6   [OIII]4959  0.082631    0.019698
# 7   [OIII]5007  0.247894    0.019698
# 8     [OI]6300  0.037439    0.015793
# 9     [OI]6364  0.012480    0.015793
# 10   [NII]6548  0.120983    0.044076
# 11   [NII]6583  0.362949    0.044076

# %%
np.median(flux_rf_rebin)
# Out:
# 0.04865061147782852
