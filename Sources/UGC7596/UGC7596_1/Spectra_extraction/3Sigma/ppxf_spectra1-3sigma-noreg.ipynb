# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/redshift.txt")
z = 0.00177 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00177

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2226559  2.22339459 2.22413328 ... 3.54048334 3.54122204 3.54196073]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3133, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3133, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
# chi2/DOF: 0.01016; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
# chi2/DOF: 0.006700; DOF: 1912; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [1.00405592 1.02071929 1.04503612 ... 0.87152923 0.89039562 0.84033312]
# [1.08235543 1.08464147 1.08027075 ... 0.91185488 0.90669033 0.89808595]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-31.69981901,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        24
#  comp.  1:        20       175
#  comp.  2:        18       179
# chi2/DOF: 1.041; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6073      0.33      20   175
# Comp:  1                Halpha     0.1464      0.33      20   175
# Comp:  2             [SII]6716     0.4476      0.34      18   179
# Comp:  2             [SII]6731    0.03874      0.34      18   179
# Comp:  2              HeII4687     0.3675      0.34      18   179
# Comp:  2               HeI5876      0.000      0.34      18   179
# Comp:  2          [OIII]5007_d     0.3469      0.43      18   179
# Comp:  2            [OI]6300_d     0.1552      0.43      18   179
# Comp:  2           [NII]6583_d     0.5473      0.43      18   179
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise: 0.8315; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise: 0.1488; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.5731; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.0981; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.6916; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.3299; gas flux:      0 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.1259; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.6036; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         7
#  comp.  1:       -13       154
#  comp.  2:        19        80
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.144      0.32     -13   154
# Comp:  1                Halpha     0.3282      0.32     -13   154
# Comp:  2             [SII]6716    0.07058      0.25      19    80
# Comp:  2             [SII]6731     0.3076      0.25      19    80
# Comp:  2              HeII4687     0.5945      0.25      19    80
# Comp:  2               HeI5876      0.000      0.25      19    80
# Comp:  2          [OIII]5007_d     0.2353      0.31      19    80
# Comp:  2            [OI]6300_d      0.000      0.31      19    80
# Comp:  2           [NII]6583_d     0.2160      0.31      19    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        60
#  comp.  1:        77       215
#  comp.  2:      -682        13
# chi2/DOF: 0.9401; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.189      0.37      77   215
# Comp:  1                Halpha     0.8180      0.43      77   215
# Comp:  2             [SII]6716    0.01311      0.20    -682    13
# Comp:  2             [SII]6731      0.000      0.20    -682    13
# Comp:  2              HeII4687    0.01618      0.20    -682    13
# Comp:  2               HeI5876      0.000      0.20    -682    13
# Comp:  2          [OIII]5007_d      0.000      0.25    -682    13
# Comp:  2            [OI]6300_d      3.660      0.25    -682    13
# Comp:  2           [NII]6583_d    0.04725      0.30    -682    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -45       175
#  comp.  2:        68       359
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.237      0.33     -45   175
# Comp:  1                Halpha     0.6864      0.34     -45   175
# Comp:  2             [SII]6716     0.4682      0.53      68   359
# Comp:  2             [SII]6731      0.000      0.53      68   359
# Comp:  2              HeII4687      0.000      0.47      68   359
# Comp:  2               HeI5876     0.7058      0.47      68   359
# Comp:  2          [OIII]5007_d     0.6777      0.59      68   359
# Comp:  2            [OI]6300_d      0.000      0.59      68   359
# Comp:  2           [NII]6583_d      0.000      0.59      68   359
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        54
#  comp.  1:       -39       397
#  comp.  2:        74         2
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.321      0.49     -39   397
# Comp:  1                Halpha     0.3186      0.49     -39   397
# Comp:  2             [SII]6716    0.02993      0.20      74     2
# Comp:  2             [SII]6731      0.000      0.20      74     2
# Comp:  2              HeII4687     0.4804      0.20      74     2
# Comp:  2               HeI5876      0.000      0.20      74     2
# Comp:  2          [OIII]5007_d    0.06644      0.25      74     2
# Comp:  2            [OI]6300_d     0.1577      0.25      74     2
# Comp:  2           [NII]6583_d     0.5003      0.25      74     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        39
#  comp.  1:       -72       372
#  comp.  2:       261         1
# chi2/DOF: 1.028; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.341      0.47     -72   372
# Comp:  1                Halpha     0.3211      0.48     -72   372
# Comp:  2             [SII]6716      0.000      0.20     261     1
# Comp:  2             [SII]6731    0.06770      0.20     261     1
# Comp:  2              HeII4687     0.7814      0.20     261     1
# Comp:  2               HeI5876      0.000      0.20     261     1
# Comp:  2          [OIII]5007_d      0.000      0.25     261     1
# Comp:  2            [OI]6300_d     0.4578      0.25     261     1
# Comp:  2           [NII]6583_d     0.2947      0.25     261     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        45
#  comp.  1:       125       163
#  comp.  2:      -522         1
# chi2/DOF: 0.9944; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 82; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5124      0.32     125   163
# Comp:  1                Halpha     0.6488      0.33     125   163
# Comp:  2             [SII]6716      0.000      0.20    -522     1
# Comp:  2             [SII]6731    0.09813      0.20    -522     1
# Comp:  2              HeII4687     0.1631      0.20    -522     1
# Comp:  2               HeI5876    0.02592      0.20    -522     1
# Comp:  2          [OIII]5007_d     0.2309      0.25    -522     1
# Comp:  2            [OI]6300_d      2.414      0.25    -522     1
# Comp:  2           [NII]6583_d      0.000      0.26    -522     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -78       212
#  comp.  2:      -140       187
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.065      0.36     -78   212
# Comp:  1                Halpha     0.2521      0.36     -78   212
# Comp:  2             [SII]6716     0.3610      0.34    -140   187
# Comp:  2             [SII]6731      0.000      0.34    -140   187
# Comp:  2              HeII4687     0.6571      0.34    -140   187
# Comp:  2               HeI5876      0.000      0.34    -140   187
# Comp:  2          [OIII]5007_d     0.4245      0.43    -140   187
# Comp:  2            [OI]6300_d     0.3528      0.43    -140   187
# Comp:  2           [NII]6583_d     0.4915      0.43    -140   187
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        17
#  comp.  1:      -113       201
#  comp.  2:       -35         1
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.117      0.35    -113   201
# Comp:  1                Halpha     0.7536      0.35    -113   201
# Comp:  2             [SII]6716     0.3252      0.20     -35     1
# Comp:  2             [SII]6731     0.3428      0.20     -35     1
# Comp:  2              HeII4687     0.2476      0.20     -35     1
# Comp:  2               HeI5876      0.000      0.20     -35     1
# Comp:  2          [OIII]5007_d     0.1636      0.25     -35     1
# Comp:  2            [OI]6300_d   0.008552      0.25     -35     1
# Comp:  2           [NII]6583_d     0.1516      0.25     -35     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -70       183
#  comp.  2:        -3        56
# chi2/DOF: 1.034; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8499      0.34     -70   183
# Comp:  1                Halpha    0.09806      0.34     -70   183
# Comp:  2             [SII]6716     0.3598      0.23      -3    56
# Comp:  2             [SII]6731      0.000      0.23      -3    56
# Comp:  2              HeII4687     0.3251      0.23      -3    56
# Comp:  2               HeI5876    0.06467      0.23      -3    56
# Comp:  2          [OIII]5007_d     0.2085      0.29      -3    56
# Comp:  2            [OI]6300_d   0.005526      0.29      -3    56
# Comp:  2           [NII]6583_d     0.4724      0.29      -3    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        27
#  comp.  1:       -59       248
#  comp.  2:       -80        74
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.328      0.39     -59   248
# Comp:  1                Halpha     0.6822      0.39     -59   248
# Comp:  2             [SII]6716      0.000      0.24     -80    74
# Comp:  2             [SII]6731      0.000      0.24     -80    74
# Comp:  2              HeII4687     0.3223      0.24     -80    74
# Comp:  2               HeI5876     0.2392      0.24     -80    74
# Comp:  2          [OIII]5007_d    0.08126      0.31     -80    74
# Comp:  2            [OI]6300_d     0.2430      0.31     -80    74
# Comp:  2           [NII]6583_d     0.3815      0.31     -80    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        17
#  comp.  1:        86       176
#  comp.  2:        55        94
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.317      0.33      86   176
# Comp:  1                Halpha     0.4980      0.33      86   176
# Comp:  2             [SII]6716     0.4192      0.26      55    94
# Comp:  2             [SII]6731     0.1458      0.26      55    94
# Comp:  2              HeII4687     0.6523      0.26      55    94
# Comp:  2               HeI5876    0.02696      0.26      55    94
# Comp:  2          [OIII]5007_d     0.3773      0.33      55    94
# Comp:  2            [OI]6300_d      0.000      0.33      55    94
# Comp:  2           [NII]6583_d     0.7724      0.33      55    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        73
#  comp.  1:       -59       290
#  comp.  2:       282       113
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.432      0.42     -59   290
# Comp:  1                Halpha     0.5726      0.43     -59   290
# Comp:  2             [SII]6716     0.4526      0.28     282   113
# Comp:  2             [SII]6731     0.1811      0.28     282   113
# Comp:  2              HeII4687      0.000      0.28     282   113
# Comp:  2               HeI5876     0.4233      0.28     282   113
# Comp:  2          [OIII]5007_d     0.1725      0.35     282   113
# Comp:  2            [OI]6300_d      0.000      0.35     282   113
# Comp:  2           [NII]6583_d     0.9990      0.36     282   113
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -56       248
#  comp.  2:        96       338
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.864      0.39     -56   248
# Comp:  1                Halpha     0.3493      0.40     -56   248
# Comp:  2             [SII]6716      1.288      0.50      96   338
# Comp:  2             [SII]6731      0.000      0.50      96   338
# Comp:  2              HeII4687     0.8411      0.45      96   338
# Comp:  2               HeI5876     0.2248      0.45      96   338
# Comp:  2          [OIII]5007_d      0.000      0.57      96   338
# Comp:  2            [OI]6300_d     0.3560      0.57      96   338
# Comp:  2           [NII]6583_d      1.417      0.58      96   338
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        33
#  comp.  1:        57      1000
#  comp.  2:       279       233
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.77      57  1000
# Comp:  1                Halpha      1.663      0.91      57  1000
# Comp:  2             [SII]6716      1.189      0.39     279   233
# Comp:  2             [SII]6731    0.01808      0.39     279   233
# Comp:  2              HeII4687     0.5508      0.38     279   233
# Comp:  2               HeI5876     0.3775      0.38     279   233
# Comp:  2          [OIII]5007_d     0.6041      0.48     279   233
# Comp:  2            [OI]6300_d     0.7842      0.48     279   233
# Comp:  2           [NII]6583_d      0.000      0.57     279   233
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:        54       111
#  comp.  2:       251       164
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.178      0.28      54   111
# Comp:  1                Halpha     0.2017      0.28      54   111
# Comp:  2             [SII]6716     0.3637      0.32     251   164
# Comp:  2             [SII]6731      0.000      0.32     251   164
# Comp:  2              HeII4687      0.000      0.32     251   164
# Comp:  2               HeI5876      0.000      0.32     251   164
# Comp:  2          [OIII]5007_d     0.7514      0.41     251   164
# Comp:  2            [OI]6300_d      0.000      0.41     251   164
# Comp:  2           [NII]6583_d     0.7414      0.41     251   164
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        34        97
#  comp.  2:        53        70
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5839      0.26      34    97
# Comp:  1                Halpha     0.1180      0.26      34    97
# Comp:  2             [SII]6716     0.1530      0.24      53    70
# Comp:  2             [SII]6731      0.000      0.24      53    70
# Comp:  2              HeII4687     0.6088      0.24      53    70
# Comp:  2               HeI5876     0.1365      0.24      53    70
# Comp:  2          [OIII]5007_d      0.000      0.30      53    70
# Comp:  2            [OI]6300_d      0.000      0.30      53    70
# Comp:  2           [NII]6583_d     0.1381      0.30      53    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -52       265
#  comp.  2:        25       193
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.264      0.40     -52   265
# Comp:  1                Halpha     0.4848      0.40     -52   265
# Comp:  2             [SII]6716     0.4826      0.35      25   193
# Comp:  2             [SII]6731     0.3610      0.35      25   193
# Comp:  2              HeII4687     0.8498      0.35      25   193
# Comp:  2               HeI5876      0.000      0.35      25   193
# Comp:  2          [OIII]5007_d     0.2984      0.44      25   193
# Comp:  2            [OI]6300_d    0.02840      0.44      25   193
# Comp:  2           [NII]6583_d     0.8350      0.44      25   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        32
#  comp.  1:       110       347
#  comp.  2:      -606       133
# chi2/DOF: 0.9736; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9475      0.46     110   347
# Comp:  1                Halpha     0.1129      0.62     110   347
# Comp:  2             [SII]6716    0.08652      0.30    -606   133
# Comp:  2             [SII]6731     0.3368      0.30    -606   133
# Comp:  2              HeII4687     0.4607      0.30    -606   133
# Comp:  2               HeI5876      0.000      0.30    -606   133
# Comp:  2          [OIII]5007_d      0.000      0.38    -606   133
# Comp:  2            [OI]6300_d      4.283      0.38    -606   133
# Comp:  2           [NII]6583_d    0.05321      0.51    -606   133
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:        -9       185
#  comp.  2:        90       108
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.809      0.34      -9   185
# Comp:  1                Halpha     0.3649      0.34      -9   185
# Comp:  2             [SII]6716     0.2904      0.27      90   108
# Comp:  2             [SII]6731      0.000      0.27      90   108
# Comp:  2              HeII4687     0.5922      0.27      90   108
# Comp:  2               HeI5876      0.000      0.27      90   108
# Comp:  2          [OIII]5007_d     0.3462      0.35      90   108
# Comp:  2            [OI]6300_d     0.3534      0.35      90   108
# Comp:  2           [NII]6583_d    0.08276      0.35      90   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        27
#  comp.  1:       -36       258
#  comp.  2:       -40       136
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.451      0.40     -36   258
# Comp:  1                Halpha     0.1087      0.40     -36   258
# Comp:  2             [SII]6716      0.000      0.30     -40   136
# Comp:  2             [SII]6731     0.6163      0.30     -40   136
# Comp:  2              HeII4687     0.4267      0.30     -40   136
# Comp:  2               HeI5876      0.000      0.30     -40   136
# Comp:  2          [OIII]5007_d  0.0004926      0.38     -40   136
# Comp:  2            [OI]6300_d    0.03035      0.38     -40   136
# Comp:  2           [NII]6583_d     0.6592      0.38     -40   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        29
#  comp.  1:      2017       114
#  comp.  2:       -83       105
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3209      0.28    2017   114
# Comp:  1                Halpha     0.1005      0.28    2017   114
# Comp:  2             [SII]6716     0.7834      0.27     -83   105
# Comp:  2             [SII]6731     0.6499      0.27     -83   105
# Comp:  2              HeII4687     0.2005      0.27     -83   105
# Comp:  2               HeI5876      0.000      0.27     -83   105
# Comp:  2          [OIII]5007_d    0.04032      0.34     -83   105
# Comp:  2            [OI]6300_d      0.000      0.34     -83   105
# Comp:  2           [NII]6583_d     0.4390      0.34     -83   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        40
#  comp.  1:      -100       332
#  comp.  2:        30       328
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.255      0.45    -100   332
# Comp:  1                Halpha     0.5857      0.46    -100   332
# Comp:  2             [SII]6716     0.4696      0.49      30   328
# Comp:  2             [SII]6731     0.1541      0.49      30   328
# Comp:  2              HeII4687     0.9359      0.45      30   328
# Comp:  2               HeI5876      0.000      0.45      30   328
# Comp:  2          [OIII]5007_d     0.3043      0.56      30   328
# Comp:  2            [OI]6300_d      0.000      0.56      30   328
# Comp:  2           [NII]6583_d      1.255      0.58      30   328
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -57       310
#  comp.  2:       -41       163
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.720      0.43     -57   310
# Comp:  1                Halpha     0.1540      0.44     -57   310
# Comp:  2             [SII]6716     0.6839      0.32     -41   163
# Comp:  2             [SII]6731     0.1557      0.32     -41   163
# Comp:  2              HeII4687     0.8552      0.32     -41   163
# Comp:  2               HeI5876      0.000      0.32     -41   163
# Comp:  2          [OIII]5007_d    0.01490      0.41     -41   163
# Comp:  2            [OI]6300_d    0.03488      0.41     -41   163
# Comp:  2           [NII]6583_d     0.3724      0.41     -41   163
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        68
#  comp.  1:      -114       137
#  comp.  2:       186       204
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7001      0.30    -114   137
# Comp:  1                Halpha     0.4660      0.30    -114   137
# Comp:  2             [SII]6716     0.7627      0.36     186   204
# Comp:  2             [SII]6731      0.000      0.36     186   204
# Comp:  2              HeII4687     0.4815      0.36     186   204
# Comp:  2               HeI5876      0.000      0.36     186   204
# Comp:  2          [OIII]5007_d     0.2953      0.45     186   204
# Comp:  2            [OI]6300_d     0.9617      0.45     186   204
# Comp:  2           [NII]6583_d      1.071      0.45     186   204
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        17
#  comp.  1:       118       243
#  comp.  2:       185         1
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.606      0.39     118   243
# Comp:  1                Halpha      0.000      0.39     118   243
# Comp:  2             [SII]6716      0.000      0.20     185     1
# Comp:  2             [SII]6731    0.07701      0.20     185     1
# Comp:  2              HeII4687    0.03427      0.20     185     1
# Comp:  2               HeI5876     0.5182      0.20     185     1
# Comp:  2          [OIII]5007_d      0.000      0.25     185     1
# Comp:  2            [OI]6300_d      0.000      0.25     185     1
# Comp:  2           [NII]6583_d     0.4036      0.25     185     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:      -102       154
#  comp.  2:       164       254
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.269      0.32    -102   154
# Comp:  1                Halpha     0.4247      0.32    -102   154
# Comp:  2             [SII]6716     0.4359      0.41     164   254
# Comp:  2             [SII]6731    0.08243      0.41     164   254
# Comp:  2              HeII4687     0.9023      0.40     164   254
# Comp:  2               HeI5876      0.000      0.40     164   254
# Comp:  2          [OIII]5007_d      0.000      0.50     164   254
# Comp:  2            [OI]6300_d      0.000      0.50     164   254
# Comp:  2           [NII]6583_d     0.5989      0.50     164   254
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        35
#  comp.  1:       -65       196
#  comp.  2:       140       120
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.747      0.35     -65   196
# Comp:  1                Halpha     0.1983      0.35     -65   196
# Comp:  2             [SII]6716    0.09962      0.29     140   120
# Comp:  2             [SII]6731     0.1388      0.29     140   120
# Comp:  2              HeII4687      1.036      0.29     140   120
# Comp:  2               HeI5876      0.000      0.29     140   120
# Comp:  2          [OIII]5007_d     0.3133      0.36     140   120
# Comp:  2            [OI]6300_d     0.2435      0.36     140   120
# Comp:  2           [NII]6583_d     0.2768      0.36     140   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        41
#  comp.  1:        31       139
#  comp.  2:        23       257
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.164      0.30      31   139
# Comp:  1                Halpha    0.03513      0.30      31   139
# Comp:  2             [SII]6716     0.6622      0.41      23   257
# Comp:  2             [SII]6731      0.000      0.41      23   257
# Comp:  2              HeII4687      1.182      0.40      23   257
# Comp:  2               HeI5876      0.000      0.40      23   257
# Comp:  2          [OIII]5007_d     0.4686      0.50      23   257
# Comp:  2            [OI]6300_d      0.000      0.50      23   257
# Comp:  2           [NII]6583_d      1.131      0.50      23   257
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:        73         1
#  comp.  2:       240         1
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2754      0.20      73     1
# Comp:  1                Halpha     0.1069      0.20      73     1
# Comp:  2             [SII]6716     0.1521      0.20     240     1
# Comp:  2             [SII]6731      0.000      0.20     240     1
# Comp:  2              HeII4687     0.7501      0.20     240     1
# Comp:  2               HeI5876     0.4757      0.20     240     1
# Comp:  2          [OIII]5007_d      0.000      0.25     240     1
# Comp:  2            [OI]6300_d      0.000      0.25     240     1
# Comp:  2           [NII]6583_d    0.08238      0.25     240     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        25
#  comp.  1:       113         9
#  comp.  2:       257       250
# chi2/DOF: 1.025; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2969      0.20     113     9
# Comp:  1                Halpha      0.000      0.20     113     9
# Comp:  2             [SII]6716     0.9983      0.40     257   250
# Comp:  2             [SII]6731      0.000      0.40     257   250
# Comp:  2              HeII4687      0.000      0.39     257   250
# Comp:  2               HeI5876    0.01641      0.39     257   250
# Comp:  2          [OIII]5007_d     0.5178      0.50     257   250
# Comp:  2            [OI]6300_d      0.000      0.50     257   250
# Comp:  2           [NII]6583_d      0.000      0.50     257   250
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        55
#  comp.  1:       -54       272
#  comp.  2:       -37        94
# chi2/DOF: 1.023; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.461      0.41     -54   272
# Comp:  1                Halpha     0.8056      0.41     -54   272
# Comp:  2             [SII]6716     0.3021      0.26     -37    94
# Comp:  2             [SII]6731     0.2938      0.26     -37    94
# Comp:  2              HeII4687     0.6054      0.26     -37    94
# Comp:  2               HeI5876     0.4820      0.26     -37    94
# Comp:  2          [OIII]5007_d     0.1812      0.33     -37    94
# Comp:  2            [OI]6300_d     0.2606      0.33     -37    94
# Comp:  2           [NII]6583_d     0.6331      0.33     -37    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        21
#  comp.  1:        28       329
#  comp.  2:       -26       118
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.491      0.45      28   329
# Comp:  1                Halpha    0.06393      0.45      28   329
# Comp:  2             [SII]6716      0.000      0.28     -26   118
# Comp:  2             [SII]6731      0.000      0.28     -26   118
# Comp:  2              HeII4687     0.5595      0.28     -26   118
# Comp:  2               HeI5876     0.3589      0.28     -26   118
# Comp:  2          [OIII]5007_d     0.2232      0.36     -26   118
# Comp:  2            [OI]6300_d     0.1490      0.36     -26   118
# Comp:  2           [NII]6583_d     0.3686      0.36     -26   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       -56       209
#  comp.  2:       226       338
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7222      0.36     -56   209
# Comp:  1                Halpha      0.000      0.37     -56   209
# Comp:  2             [SII]6716     0.5844      0.50     226   338
# Comp:  2             [SII]6731      0.000      0.50     226   338
# Comp:  2              HeII4687     0.8513      0.45     226   338
# Comp:  2               HeI5876      1.150      0.45     226   338
# Comp:  2          [OIII]5007_d     0.1536      0.57     226   338
# Comp:  2            [OI]6300_d      0.000      0.57     226   338
# Comp:  2           [NII]6583_d      0.000      0.58     226   338
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        39
#  comp.  1:       -35       253
#  comp.  2:       -63       131
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.856      0.39     -35   253
# Comp:  1                Halpha     0.5417      0.39     -35   253
# Comp:  2             [SII]6716     0.4356      0.30     -63   131
# Comp:  2             [SII]6731     0.6977      0.30     -63   131
# Comp:  2              HeII4687     0.3744      0.30     -63   131
# Comp:  2               HeI5876     0.2403      0.30     -63   131
# Comp:  2          [OIII]5007_d      0.000      0.37     -63   131
# Comp:  2            [OI]6300_d     0.2013      0.37     -63   131
# Comp:  2           [NII]6583_d     0.4629      0.37     -63   131
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        30
#  comp.  1:       114         1
#  comp.  2:       185         1
# chi2/DOF: 1.028; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2482      0.20     114     1
# Comp:  1                Halpha     0.1681      0.20     114     1
# Comp:  2             [SII]6716      0.000      0.20     185     1
# Comp:  2             [SII]6731     0.1103      0.20     185     1
# Comp:  2              HeII4687     0.2544      0.20     185     1
# Comp:  2               HeI5876     0.4987      0.20     185     1
# Comp:  2          [OIII]5007_d      0.000      0.25     185     1
# Comp:  2            [OI]6300_d      0.000      0.25     185     1
# Comp:  2           [NII]6583_d      0.000      0.25     185     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        38
#  comp.  1:       311       635
#  comp.  2:       -75       238
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.413      0.62     311   635
# Comp:  1                Halpha      0.000      0.80     311   635
# Comp:  2             [SII]6716      1.019      0.39     -75   238
# Comp:  2             [SII]6731     0.8752      0.39     -75   238
# Comp:  2              HeII4687     0.8257      0.38     -75   238
# Comp:  2               HeI5876     0.2273      0.38     -75   238
# Comp:  2          [OIII]5007_d     0.4037      0.48     -75   238
# Comp:  2            [OI]6300_d      0.000      0.48     -75   238
# Comp:  2           [NII]6583_d     0.6346      0.63     -75   238
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:        13        45
#  comp.  2:       -11       149
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2914      0.22      13    45
# Comp:  1                Halpha     0.1509      0.22      13    45
# Comp:  2             [SII]6716      0.000      0.31     -11   149
# Comp:  2             [SII]6731     0.4249      0.31     -11   149
# Comp:  2              HeII4687     0.7799      0.31     -11   149
# Comp:  2               HeI5876      0.000      0.31     -11   149
# Comp:  2          [OIII]5007_d     0.2461      0.39     -11   149
# Comp:  2            [OI]6300_d    0.07019      0.39     -11   149
# Comp:  2           [NII]6583_d     0.8205      0.39     -11   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:        37       199
#  comp.  2:        13       203
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6360      0.35      37   199
# Comp:  1                Halpha     0.6472      0.35      37   199
# Comp:  2             [SII]6716     0.1626      0.36      13   203
# Comp:  2             [SII]6731     0.5488      0.36      13   203
# Comp:  2              HeII4687     0.2994      0.36      13   203
# Comp:  2               HeI5876      0.000      0.36      13   203
# Comp:  2          [OIII]5007_d     0.5307      0.45      13   203
# Comp:  2            [OI]6300_d      0.000      0.45      13   203
# Comp:  2           [NII]6583_d     0.6701      0.45      13   203
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        50
#  comp.  1:      -106       132
#  comp.  2:      -528        58
# chi2/DOF: 1.005; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8686      0.30    -106   132
# Comp:  1                Halpha     0.4885      0.30    -106   132
# Comp:  2             [SII]6716     0.1028      0.23    -528    58
# Comp:  2             [SII]6731      0.000      0.23    -528    58
# Comp:  2              HeII4687      0.000      0.23    -528    58
# Comp:  2               HeI5876    0.02893      0.23    -528    58
# Comp:  2          [OIII]5007_d      0.000      0.29    -528    58
# Comp:  2            [OI]6300_d      2.458      0.29    -528    58
# Comp:  2           [NII]6583_d   0.006220      0.29    -528    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        37
#  comp.  1:       -21       337
#  comp.  2:       104       216
# chi2/DOF: 1.025; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.470      0.45     -21   337
# Comp:  1                Halpha     0.8711      0.46     -21   337
# Comp:  2             [SII]6716     0.1709      0.37     104   216
# Comp:  2             [SII]6731      0.000      0.37     104   216
# Comp:  2              HeII4687      1.508      0.37     104   216
# Comp:  2               HeI5876     0.2959      0.37     104   216
# Comp:  2          [OIII]5007_d    0.09858      0.46     104   216
# Comp:  2            [OI]6300_d     0.3787      0.46     104   216
# Comp:  2           [NII]6583_d     0.3617      0.47     104   216
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -47       292
#  comp.  2:      -535         1
# chi2/DOF: 0.9976; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 119; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.186      0.42     -47   292
# Comp:  1                Halpha      0.000      0.43     -47   292
# Comp:  2             [SII]6716   0.002838      0.20    -535     1
# Comp:  2             [SII]6731    0.05398      0.20    -535     1
# Comp:  2              HeII4687      0.000      0.20    -535     1
# Comp:  2               HeI5876      0.000      0.20    -535     1
# Comp:  2          [OIII]5007_d     0.3190      0.25    -535     1
# Comp:  2            [OI]6300_d      2.113      0.25    -535     1
# Comp:  2           [NII]6583_d      0.000      0.26    -535     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93         1
#  comp.  1:       -99       324
#  comp.  2:      -148       104
# chi2/DOF: 1.030; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.326      0.44     -99   324
# Comp:  1                Halpha      1.043      0.44     -99   324
# Comp:  2             [SII]6716     0.1573      0.27    -148   104
# Comp:  2             [SII]6731     0.4784      0.27    -148   104
# Comp:  2              HeII4687     0.2064      0.27    -148   104
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.938      0.46      92   353
# Comp:  1                Halpha     0.6288      0.67      92   353
# Comp:  2             [SII]6716     0.3027       1.2    -284   730
# Comp:  2             [SII]6731     0.7201       1.2    -284   730
# Comp:  2              HeII4687      1.478      0.66    -284   730
# Comp:  2               HeI5876     0.5628      0.66    -284   730
# Comp:  2          [OIII]5007_d      1.669      0.83    -284   730
# Comp:  2            [OI]6300_d      2.605      0.83    -284   730
# Comp:  2           [NII]6583_d     0.5855       1.1    -284   730
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:      -115      1000
#  comp.  2:      -179       156
# chi2/DOF: 1.026; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.232      0.77    -115  1000
# Comp:  1                Halpha      1.003      0.90    -115  1000
# Comp:  2             [SII]6716     0.6863      0.32    -179   156
# Comp:  2             [SII]6731     0.6139      0.32    -179   156
# Comp:  2              HeII4687     0.7475      0.32    -179   156
# Comp:  2               HeI5876      0.000      0.32    -179   156
# Comp:  2          [OIII]5007_d    0.08991      0.40    -179   156
# Comp:  2            [OI]6300_d     0.6548      0.40    -179   156
# Comp:  2           [NII]6583_d    0.07270      0.47    -179   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:         9       250
#  comp.  2:        11       358
# chi2/DOF: 1.025; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.193      0.39       9   250
# Comp:  1                Halpha     0.3030      0.40       9   250
# Comp:  2             [SII]6716     0.4136      0.52      11   358
# Comp:  2             [SII]6731      0.000      0.52      11   358
# Comp:  2              HeII4687      1.136      0.47      11   358
# Comp:  2               HeI5876     0.2299      0.47      11   358
# Comp:  2          [OIII]5007_d      1.249      0.59      11   358
# Comp:  2            [OI]6300_d      1.647      0.59      11   358
# Comp:  2           [NII]6583_d     0.4507      0.60      11   358
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -12       138
#  comp.  2:      -531         1
# chi2/DOF: 1.003; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.154      0.30     -12   138
# Comp:  1                Halpha     0.2259      0.30     -12   138
# Comp:  2             [SII]6716      0.000      0.20    -531     1
# Comp:  2             [SII]6731    0.06445      0.20    -531     1
# Comp:  2              HeII4687     0.2856      0.20    -531     1
# Comp:  2               HeI5876      0.000      0.20    -531     1
# Comp:  2          [OIII]5007_d      0.000      0.25    -531     1
# Comp:  2            [OI]6300_d      2.211      0.25    -531     1
# Comp:  2           [NII]6583_d      0.000      0.25    -531     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       129         1
#  comp.  2:        92       171
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2592      0.20     129     1
# Comp:  1                Halpha     0.2058      0.20     129     1
# Comp:  2             [SII]6716     0.3252      0.33      92   171
# Comp:  2             [SII]6731   0.005782      0.33      92   171
# Comp:  2              HeII4687     0.8109      0.33      92   171
# Comp:  2               HeI5876      0.000      0.33      92   171
# Comp:  2          [OIII]5007_d     0.6832      0.42      92   171
# Comp:  2            [OI]6300_d      0.000      0.42      92   171
# Comp:  2           [NII]6583_d   0.006027      0.42      92   171
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        52
#  comp.  1:       133        77
#  comp.  2:       166         1
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3983      0.25     133    77
# Comp:  1                Halpha      0.000      0.25     133    77
# Comp:  2             [SII]6716   0.005361      0.20     166     1
# Comp:  2             [SII]6731      0.000      0.20     166     1
# Comp:  2              HeII4687     0.5000      0.20     166     1
# Comp:  2               HeI5876     0.4746      0.20     166     1
# Comp:  2          [OIII]5007_d      0.000      0.25     166     1
# Comp:  2            [OI]6300_d      0.000      0.25     166     1
# Comp:  2           [NII]6583_d     0.2036      0.25     166     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:        35       335
#  comp.  2:      -112       148
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.399      0.45      35   335
# Comp:  1                Halpha      0.000      0.45      35   335
# Comp:  2             [SII]6716     0.2614      0.31    -112   148
# Comp:  2             [SII]6731     0.6517      0.31    -112   148
# Comp:  2              HeII4687     0.4607      0.31    -112   148
# Comp:  2               HeI5876     0.1391      0.31    -112   148
# Comp:  2          [OIII]5007_d     0.2454      0.39    -112   148
# Comp:  2            [OI]6300_d      0.000      0.39    -112   148
# Comp:  2           [NII]6583_d     0.5335      0.40    -112   148
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        39
#  comp.  1:        73       170
#  comp.  2:         3       143
# chi2/DOF: 1.035; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6422      0.33      73   170
# Comp:  1                Halpha     0.6014      0.33      73   170
# Comp:  2             [SII]6716     0.1452      0.31       3   143
# Comp:  2             [SII]6731      0.000      0.31       3   143
# Comp:  2              HeII4687     0.6757      0.31       3   143
# Comp:  2               HeI5876     0.1563      0.31       3   143
# Comp:  2          [OIII]5007_d     0.1786      0.39       3   143
# Comp:  2            [OI]6300_d      0.000      0.39       3   143
# Comp:  2           [NII]6583_d     0.3674      0.39       3   143
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        43
#  comp.  1:       -92       255
#  comp.  2:       257         1
# chi2/DOF: 1.025; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.379      0.40     -92   255
# Comp:  1                Halpha     0.3139      0.40     -92   255
# Comp:  2             [SII]6716      0.000      0.20     257     1
# Comp:  2             [SII]6731      0.000      0.20     257     1
# Comp:  2              HeII4687     0.7130      0.20     257     1
# Comp:  2               HeI5876     0.3498      0.20     257     1
# Comp:  2          [OIII]5007_d     0.3869      0.25     257     1
# Comp:  2            [OI]6300_d     0.4698      0.25     257     1
# Comp:  2           [NII]6583_d    0.08607      0.25     257     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:       -69       239
#  comp.  2:        -7       171
# chi2/DOF: 1.027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.38     -69   239
# Comp:  1                Halpha     0.4550      0.38     -69   239
# Comp:  2             [SII]6716     0.4048      0.33      -7   171
# Comp:  2             [SII]6731      0.000      0.33      -7   171
# Comp:  2              HeII4687     0.5237      0.33      -7   171
# Comp:  2               HeI5876      0.000      0.33      -7   171
# Comp:  2          [OIII]5007_d     0.5911      0.42      -7   171
# Comp:  2            [OI]6300_d     0.4214      0.42      -7   171
# Comp:  2           [NII]6583_d     0.5787      0.42      -7   171
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:        41       345
#  comp.  2:       226        98
# chi2/DOF: 1.031; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.487      0.46      41   345
# Comp:  1                Halpha    0.03352      0.46      41   345
# Comp:  2             [SII]6716      0.000      0.27     226    98
# Comp:  2             [SII]6731      0.000      0.27     226    98
# Comp:  2              HeII4687     0.8978      0.27     226    98
# Comp:  2               HeI5876      0.000      0.27     226    98
# Comp:  2          [OIII]5007_d      0.000      0.34     226    98
# Comp:  2            [OI]6300_d      0.000      0.34     226    98
# Comp:  2           [NII]6583_d     0.4264      0.34     226    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        13
#  comp.  1:       -68       245
#  comp.  2:        90       279
# chi2/DOF: 1.029; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.208      0.39     -68   245
# Comp:  1                Halpha     0.5281      0.39     -68   245
# Comp:  2             [SII]6716      0.000      0.43      90   279
# Comp:  2             [SII]6731      0.000      0.43      90   279
# Comp:  2              HeII4687     0.4387      0.41      90   279
# Comp:  2               HeI5876     0.4407      0.41      90   279
# Comp:  2          [OIII]5007_d     0.5756      0.52      90   279
# Comp:  2            [OI]6300_d   0.008112      0.52      90   279
# Comp:  2           [NII]6583_d     0.1477      0.53      90   279
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        40
#  comp.  1:       145       214
#  comp.  2:        22       233
# chi2/DOF: 1.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.37     145   214
# Comp:  1                Halpha     0.8300      0.37     145   214
# Comp:  2             [SII]6716     0.4664      0.39      22   233
# Comp:  2             [SII]6731      0.000      0.39      22   233
# Comp:  2              HeII4687     0.9762      0.38      22   233
# Comp:  2               HeI5876     0.1084      0.38      22   233
# Comp:  2          [OIII]5007_d    0.07899      0.48      22   233
# Comp:  2            [OI]6300_d    0.01246      0.48      22   233
# Comp:  2           [NII]6583_d     0.5177      0.48      22   233
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:        -4       286
#  comp.  2:        85       107
# chi2/DOF: 1.032; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.223      0.42      -4   286
# Comp:  1                Halpha     0.4259      0.42      -4   286
# Comp:  2             [SII]6716     0.4519      0.27      85   107
# Comp:  2             [SII]6731      0.000      0.27      85   107
# Comp:  2              HeII4687     0.1779      0.27      85   107
# Comp:  2               HeI5876     0.3359      0.27      85   107
# Comp:  2          [OIII]5007_d     0.4607      0.35      85   107
# Comp:  2            [OI]6300_d     0.1101      0.35      85   107
# Comp:  2           [NII]6583_d     0.1094      0.35      85   107
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.11846361, 0.47723756, 0.4499919 , 0.28299085, 0.43344987,
#        0.31614381, 0.29179578, 0.99453662, 0.48136953])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.52744626, 0.12748877, 0.51727776, 0.08869106, 0.43755809,
#        0.        , 0.29863162, 0.14191408, 0.70945692])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0         Hbeta  0.046423    0.098442
# 1        Halpha  0.011221    0.042004
# 2     [SII]6716  0.045528    0.039606
# 3     [SII]6731  0.007806    0.024908
# 4      HeII4687  0.038512    0.038150
# 5       HeI5876  0.000000    0.027826
# 6  [OIII]5007_d  0.026284    0.025683
# 7    [OI]6300_d  0.012491    0.087535
# 8   [NII]6583_d  0.062443    0.042368
#           Name      Flux  Error_flux
# 0        Hbeta  0.046423    0.098442
# 1       Halpha  0.011221    0.042004
# 2    [SII]6716  0.045528    0.039606
# 3    [SII]6731  0.007806    0.024908
# 4     HeII4687  0.038512    0.038150
# 5      HeI5876  0.000000    0.027826
# 6   [OIII]4959  0.006571    0.025683
# 7   [OIII]5007  0.019713    0.025683
# 8     [OI]6300  0.009368    0.087535
# 9     [OI]6364  0.003123    0.087535
# 10   [NII]6548  0.015611    0.042368
# 11   [NII]6583  0.046832    0.042368

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0880153829332782
