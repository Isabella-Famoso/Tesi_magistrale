# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_11.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_11']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02397953 0.04174084 0.02154482 ... 0.02595162 0.02574091 0.02279601] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         7       124
# chi2/DOF: 0.04291; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:        45        91
# chi2/DOF: 0.03094; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([45.00190811, 90.75226405])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        30       109
#  comp.  1:       121       205
#  comp.  2:       -52        82
# chi2/DOF: 0.9141; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.718      0.78     121   205
# Comp:  1                Halpha      2.474      0.78     121   205
# Comp:  2             [SII]6716      2.670      0.54     -52    82
# Comp:  2             [SII]6731     0.2841      0.54     -52    82
# Comp:  2              HeII4687     0.2219      0.54     -52    82
# Comp:  2               HeI5876      0.000      0.54     -52    82
# Comp:  2          [OIII]5007_d     0.1123      0.69     -52    82
# Comp:  2            [OI]6300_d      1.902      0.69     -52    82
# Comp:  2           [NII]6583_d     0.9592      0.69     -52    82
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  3.694; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  1.603; gas flux:      3 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  3.467; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.3641; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.2925; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.1116; gas flux:      0 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.855; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.9218; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        62       146
#  comp.  1:       148       217
#  comp.  2:       -62        83
# chi2/DOF: 0.9055; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.689      0.80     148   217
# Comp:  1                Halpha      4.502      0.80     148   217
# Comp:  2             [SII]6716      2.637      0.55     -62    83
# Comp:  2             [SII]6731     0.3066      0.55     -62    83
# Comp:  2              HeII4687     0.6070      0.55     -62    83
# Comp:  2               HeI5876     0.4258      0.55     -62    83
# Comp:  2          [OIII]5007_d      0.000      0.69     -62    83
# Comp:  2            [OI]6300_d      2.200      0.69     -62    83
# Comp:  2           [NII]6583_d     0.4059      0.69     -62    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18       131
#  comp.  1:        91       235
#  comp.  2:       -34        93
# chi2/DOF: 0.9008; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.660      0.83      91   235
# Comp:  1                Halpha      5.109      0.83      91   235
# Comp:  2             [SII]6716      2.650      0.56     -34    93
# Comp:  2             [SII]6731     0.4697      0.56     -34    93
# Comp:  2              HeII4687     0.4043      0.56     -34    93
# Comp:  2               HeI5876     0.4372      0.56     -34    93
# Comp:  2          [OIII]5007_d     0.2132      0.71     -34    93
# Comp:  2            [OI]6300_d      1.727      0.71     -34    93
# Comp:  2           [NII]6583_d      1.606      0.71     -34    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        76
#  comp.  1:        45       223
#  comp.  2:       -79        85
# chi2/DOF: 0.9063; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.116      0.81      45   223
# Comp:  1                Halpha      2.727      0.81      45   223
# Comp:  2             [SII]6716      2.531      0.55     -79    85
# Comp:  2             [SII]6731     0.3123      0.55     -79    85
# Comp:  2              HeII4687     0.2762      0.55     -79    85
# Comp:  2               HeI5876      0.000      0.55     -79    85
# Comp:  2          [OIII]5007_d      1.013      0.69     -79    85
# Comp:  2            [OI]6300_d      1.886      0.69     -79    85
# Comp:  2           [NII]6583_d     0.7507      0.69     -79    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67       310
#  comp.  1:       195       265
#  comp.  2:       -34       120
# chi2/DOF: 0.9023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.885      0.87     195   265
# Comp:  1                Halpha      4.108      0.88     195   265
# Comp:  2             [SII]6716      3.178      0.62     -34   120
# Comp:  2             [SII]6731     0.5457      0.62     -34   120
# Comp:  2              HeII4687      0.000      0.62     -34   120
# Comp:  2               HeI5876     0.5031      0.62     -34   120
# Comp:  2          [OIII]5007_d     0.4517      0.78     -34   120
# Comp:  2            [OI]6300_d      3.069      0.78     -34   120
# Comp:  2           [NII]6583_d      1.750      0.78     -34   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3       169
#  comp.  1:        83       224
#  comp.  2:       -62        96
# chi2/DOF: 0.9051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.836      0.81      83   224
# Comp:  1                Halpha      2.243      0.81      83   224
# Comp:  2             [SII]6716      2.665      0.57     -62    96
# Comp:  2             [SII]6731     0.2524      0.57     -62    96
# Comp:  2              HeII4687      1.139      0.57     -62    96
# Comp:  2               HeI5876      0.000      0.57     -62    96
# Comp:  2          [OIII]5007_d     0.4176      0.72     -62    96
# Comp:  2            [OI]6300_d      2.597      0.72     -62    96
# Comp:  2           [NII]6583_d     0.8211      0.72     -62    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13       115
#  comp.  1:       116       254
#  comp.  2:       -44       101
# chi2/DOF: 0.9096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.486      0.86     116   254
# Comp:  1                Halpha      2.794      0.86     116   254
# Comp:  2             [SII]6716      3.030      0.58     -44   101
# Comp:  2             [SII]6731     0.5277      0.58     -44   101
# Comp:  2              HeII4687     0.8462      0.58     -44   101
# Comp:  2               HeI5876     0.1589      0.58     -44   101
# Comp:  2          [OIII]5007_d     0.2193      0.73     -44   101
# Comp:  2            [OI]6300_d      2.095      0.73     -44   101
# Comp:  2           [NII]6583_d      1.291      0.73     -44   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        88
#  comp.  1:       121       217
#  comp.  2:       -60        82
# chi2/DOF: 0.9092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.079      0.80     121   217
# Comp:  1                Halpha      3.630      0.80     121   217
# Comp:  2             [SII]6716      2.220      0.54     -60    82
# Comp:  2             [SII]6731    0.04838      0.54     -60    82
# Comp:  2              HeII4687     0.5218      0.54     -60    82
# Comp:  2               HeI5876      0.000      0.54     -60    82
# Comp:  2          [OIII]5007_d      0.000      0.69     -60    82
# Comp:  2            [OI]6300_d      1.907      0.69     -60    82
# Comp:  2           [NII]6583_d      1.153      0.69     -60    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17       123
#  comp.  1:        99       145
#  comp.  2:       -50        69
# chi2/DOF: 0.9051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.552      0.67      99   145
# Comp:  1                Halpha      2.252      0.67      99   145
# Comp:  2             [SII]6716      2.754      0.52     -50    69
# Comp:  2             [SII]6731     0.1210      0.52     -50    69
# Comp:  2              HeII4687     0.8111      0.52     -50    69
# Comp:  2               HeI5876     0.4603      0.52     -50    69
# Comp:  2          [OIII]5007_d      0.000      0.65     -50    69
# Comp:  2            [OI]6300_d      1.730      0.65     -50    69
# Comp:  2           [NII]6583_d     0.8790      0.65     -50    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        63
#  comp.  1:       121       187
#  comp.  2:       -36        75
# chi2/DOF: 0.9036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.902      0.74     121   187
# Comp:  1                Halpha      2.221      0.74     121   187
# Comp:  2             [SII]6716      2.655      0.53     -36    75
# Comp:  2             [SII]6731     0.3544      0.53     -36    75
# Comp:  2              HeII4687    0.05328      0.53     -36    75
# Comp:  2               HeI5876     0.5482      0.53     -36    75
# Comp:  2          [OIII]5007_d     0.4118      0.67     -36    75
# Comp:  2            [OI]6300_d      1.768      0.67     -36    75
# Comp:  2           [NII]6583_d      1.012      0.67     -36    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       131
#  comp.  1:       114       219
#  comp.  2:       -62       102
# chi2/DOF: 0.9065; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.533      0.80     114   219
# Comp:  1                Halpha      1.904      0.80     114   219
# Comp:  2             [SII]6716      2.785      0.58     -62   102
# Comp:  2             [SII]6731     0.3136      0.58     -62   102
# Comp:  2              HeII4687      0.000      0.58     -62   102
# Comp:  2               HeI5876     0.9230      0.58     -62   102
# Comp:  2          [OIII]5007_d     0.4263      0.74     -62   102
# Comp:  2            [OI]6300_d      2.155      0.74     -62   102
# Comp:  2           [NII]6583_d     0.7741      0.74     -62   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40       146
#  comp.  1:       105       235
#  comp.  2:       -73        71
# chi2/DOF: 0.9108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.496      0.83     105   235
# Comp:  1                Halpha      2.473      0.83     105   235
# Comp:  2             [SII]6716      2.488      0.52     -73    71
# Comp:  2             [SII]6731     0.1921      0.52     -73    71
# Comp:  2              HeII4687     0.4179      0.52     -73    71
# Comp:  2               HeI5876     0.1255      0.52     -73    71
# Comp:  2          [OIII]5007_d      0.000      0.66     -73    71
# Comp:  2            [OI]6300_d      1.680      0.66     -73    71
# Comp:  2           [NII]6583_d      1.009      0.66     -73    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        71       261
#  comp.  1:       139       208
#  comp.  2:       -42        92
# chi2/DOF: 0.9038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.920      0.78     139   208
# Comp:  1                Halpha      3.379      0.78     139   208
# Comp:  2             [SII]6716      2.526      0.56     -42    92
# Comp:  2             [SII]6731     0.3202      0.56     -42    92
# Comp:  2              HeII4687      1.294      0.56     -42    92
# Comp:  2               HeI5876      0.000      0.56     -42    92
# Comp:  2          [OIII]5007_d     0.1150      0.71     -42    92
# Comp:  2            [OI]6300_d      1.461      0.71     -42    92
# Comp:  2           [NII]6583_d      1.145      0.71     -42    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        91
#  comp.  1:       105       144
#  comp.  2:       -42       102
# chi2/DOF: 0.9059; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.212      0.67     105   144
# Comp:  1                Halpha      1.885      0.67     105   144
# Comp:  2             [SII]6716      2.799      0.58     -42   102
# Comp:  2             [SII]6731     0.2433      0.58     -42   102
# Comp:  2              HeII4687     0.6616      0.58     -42   102
# Comp:  2               HeI5876     0.6018      0.58     -42   102
# Comp:  2          [OIII]5007_d     0.4952      0.74     -42   102
# Comp:  2            [OI]6300_d      1.785      0.74     -42   102
# Comp:  2           [NII]6583_d      1.618      0.74     -42   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41       189
#  comp.  1:       130       270
#  comp.  2:       -61        70
# chi2/DOF: 0.9031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.50      0.88     130   270
# Comp:  1                Halpha      3.496      0.88     130   270
# Comp:  2             [SII]6716      2.616      0.52     -61    70
# Comp:  2             [SII]6731     0.2024      0.52     -61    70
# Comp:  2              HeII4687     0.5379      0.52     -61    70
# Comp:  2               HeI5876    0.06211      0.52     -61    70
# Comp:  2          [OIII]5007_d      0.000      0.66     -61    70
# Comp:  2            [OI]6300_d      1.631      0.66     -61    70
# Comp:  2           [NII]6583_d      1.086      0.66     -61    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36       118
#  comp.  1:       118       232
#  comp.  2:       -35        85
# chi2/DOF: 0.9053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.075      0.82     118   232
# Comp:  1                Halpha      3.404      0.82     118   232
# Comp:  2             [SII]6716      2.836      0.55     -35    85
# Comp:  2             [SII]6731     0.1629      0.55     -35    85
# Comp:  2              HeII4687      0.000      0.55     -35    85
# Comp:  2               HeI5876      0.000      0.55     -35    85
# Comp:  2          [OIII]5007_d     0.8133      0.69     -35    85
# Comp:  2            [OI]6300_d      2.095      0.69     -35    85
# Comp:  2           [NII]6583_d     0.8903      0.69     -35    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44        71
#  comp.  1:       114       196
#  comp.  2:       -62        55
# chi2/DOF: 0.9066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.504      0.76     114   196
# Comp:  1                Halpha      3.058      0.76     114   196
# Comp:  2             [SII]6716      2.418      0.49     -62    55
# Comp:  2             [SII]6731     0.4295      0.49     -62    55
# Comp:  2              HeII4687     0.4557      0.49     -62    55
# Comp:  2               HeI5876    0.06282      0.49     -62    55
# Comp:  2          [OIII]5007_d      0.000      0.62     -62    55
# Comp:  2            [OI]6300_d      1.631      0.62     -62    55
# Comp:  2           [NII]6583_d      1.261      0.62     -62    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15        79
#  comp.  1:        90       234
#  comp.  2:       -97       131
# chi2/DOF: 0.9047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.257      0.82      90   234
# Comp:  1                Halpha      4.848      0.82      90   234
# Comp:  2             [SII]6716      3.336      0.64     -97   131
# Comp:  2             [SII]6731     0.6379      0.64     -97   131
# Comp:  2              HeII4687     0.2286      0.64     -97   131
# Comp:  2               HeI5876     0.5657      0.64     -97   131
# Comp:  2          [OIII]5007_d     0.6028      0.81     -97   131
# Comp:  2            [OI]6300_d      2.840      0.81     -97   131
# Comp:  2           [NII]6583_d      1.615      0.81     -97   131
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        76       107
#  comp.  1:       170       164
#  comp.  2:       -82        94
# chi2/DOF: 0.9057; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.215      0.70     170   164
# Comp:  1                Halpha      2.356      0.70     170   164
# Comp:  2             [SII]6716      2.694      0.57     -82    94
# Comp:  2             [SII]6731     0.3167      0.57     -82    94
# Comp:  2              HeII4687     0.7860      0.57     -82    94
# Comp:  2               HeI5876     0.1629      0.57     -82    94
# Comp:  2          [OIII]5007_d      0.000      0.72     -82    94
# Comp:  2            [OI]6300_d      2.443      0.72     -82    94
# Comp:  2           [NII]6583_d      1.047      0.72     -82    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4       157
#  comp.  1:       153       197
#  comp.  2:       -71        86
# chi2/DOF: 0.9070; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.833      0.76     153   197
# Comp:  1                Halpha      1.756      0.76     153   197
# Comp:  2             [SII]6716      2.623      0.55     -71    86
# Comp:  2             [SII]6731    0.04792      0.55     -71    86
# Comp:  2              HeII4687     0.1052      0.55     -71    86
# Comp:  2               HeI5876      0.000      0.55     -71    86
# Comp:  2          [OIII]5007_d      0.000      0.70     -71    86
# Comp:  2            [OI]6300_d      1.890      0.70     -71    86
# Comp:  2           [NII]6583_d     0.2234      0.70     -71    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29       157
#  comp.  1:       107       259
#  comp.  2:       -36        49
# chi2/DOF: 0.9041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.06      0.87     107   259
# Comp:  1                Halpha      4.686      0.87     107   259
# Comp:  2             [SII]6716      2.493      0.48     -36    49
# Comp:  2             [SII]6731     0.1501      0.48     -36    49
# Comp:  2              HeII4687     0.4364      0.48     -36    49
# Comp:  2               HeI5876     0.6538      0.48     -36    49
# Comp:  2          [OIII]5007_d     0.2533      0.61     -36    49
# Comp:  2            [OI]6300_d      1.679      0.61     -36    49
# Comp:  2           [NII]6583_d     0.7048      0.61     -36    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37       165
#  comp.  1:       128       267
#  comp.  2:       -94       109
# chi2/DOF: 0.9071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.532      0.88     128   267
# Comp:  1                Halpha      3.178      0.88     128   267
# Comp:  2             [SII]6716      2.637      0.60     -94   109
# Comp:  2             [SII]6731      0.000      0.60     -94   109
# Comp:  2              HeII4687     0.1251      0.60     -94   109
# Comp:  2               HeI5876      0.000      0.60     -94   109
# Comp:  2          [OIII]5007_d      0.000      0.76     -94   109
# Comp:  2            [OI]6300_d      1.712      0.76     -94   109
# Comp:  2           [NII]6583_d     0.9096      0.76     -94   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26       115
#  comp.  1:       108       229
#  comp.  2:       -54        97
# chi2/DOF: 0.9065; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.983      0.82     108   229
# Comp:  1                Halpha      5.435      0.82     108   229
# Comp:  2             [SII]6716      2.772      0.57     -54    97
# Comp:  2             [SII]6731     0.3382      0.57     -54    97
# Comp:  2              HeII4687     0.6266      0.57     -54    97
# Comp:  2               HeI5876      0.000      0.57     -54    97
# Comp:  2          [OIII]5007_d      0.000      0.72     -54    97
# Comp:  2            [OI]6300_d      2.764      0.72     -54    97
# Comp:  2           [NII]6583_d      1.543      0.72     -54    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17       113
#  comp.  1:        97       198
#  comp.  2:       -54        73
# chi2/DOF: 0.9022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.670      0.76      97   198
# Comp:  1                Halpha      3.191      0.76      97   198
# Comp:  2             [SII]6716      2.381      0.53     -54    73
# Comp:  2             [SII]6731     0.1439      0.53     -54    73
# Comp:  2              HeII4687     0.4244      0.53     -54    73
# Comp:  2               HeI5876     0.5109      0.53     -54    73
# Comp:  2          [OIII]5007_d      0.000      0.66     -54    73
# Comp:  2            [OI]6300_d      1.698      0.66     -54    73
# Comp:  2           [NII]6583_d     0.8364      0.66     -54    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35       137
#  comp.  1:       118       164
#  comp.  2:       -39        91
# chi2/DOF: 0.9066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.405      0.70     118   164
# Comp:  1                Halpha      1.581      0.70     118   164
# Comp:  2             [SII]6716      2.525      0.56     -39    91
# Comp:  2             [SII]6731     0.3874      0.56     -39    91
# Comp:  2              HeII4687     0.6678      0.56     -39    91
# Comp:  2               HeI5876      0.000      0.56     -39    91
# Comp:  2          [OIII]5007_d     0.4595      0.71     -39    91
# Comp:  2            [OI]6300_d      2.411      0.71     -39    91
# Comp:  2           [NII]6583_d     0.3777      0.71     -39    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       111       208
#  comp.  1:       145       274
#  comp.  2:       -36        89
# chi2/DOF: 0.9019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.91      0.89     145   274
# Comp:  1                Halpha      4.948      0.89     145   274
# Comp:  2             [SII]6716      2.761      0.56     -36    89
# Comp:  2             [SII]6731     0.3326      0.56     -36    89
# Comp:  2              HeII4687    0.04509      0.56     -36    89
# Comp:  2               HeI5876    0.02589      0.56     -36    89
# Comp:  2          [OIII]5007_d     0.8191      0.70     -36    89
# Comp:  2            [OI]6300_d      2.451      0.70     -36    89
# Comp:  2           [NII]6583_d      1.047      0.71     -36    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        68        78
#  comp.  1:       157       164
#  comp.  2:       -69        72
# chi2/DOF: 0.9044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.440      0.70     157   164
# Comp:  1                Halpha      1.088      0.70     157   164
# Comp:  2             [SII]6716      2.544      0.52     -69    72
# Comp:  2             [SII]6731     0.4650      0.52     -69    72
# Comp:  2              HeII4687   0.007901      0.52     -69    72
# Comp:  2               HeI5876      0.000      0.52     -69    72
# Comp:  2          [OIII]5007_d     0.9600      0.66     -69    72
# Comp:  2            [OI]6300_d      1.771      0.66     -69    72
# Comp:  2           [NII]6583_d      1.178      0.66     -69    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34       124
#  comp.  1:       153       170
#  comp.  2:       -66       110
# chi2/DOF: 0.9053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.548      0.72     153   170
# Comp:  1                Halpha      2.800      0.72     153   170
# Comp:  2             [SII]6716      2.677      0.60     -66   110
# Comp:  2             [SII]6731     0.5541      0.60     -66   110
# Comp:  2              HeII4687     0.6018      0.60     -66   110
# Comp:  2               HeI5876      0.000      0.60     -66   110
# Comp:  2          [OIII]5007_d      0.000      0.76     -66   110
# Comp:  2            [OI]6300_d      2.323      0.76     -66   110
# Comp:  2           [NII]6583_d     0.2560      0.76     -66   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12       144
#  comp.  1:       117       210
#  comp.  2:       -63        90
# chi2/DOF: 0.9069; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.513      0.79     117   210
# Comp:  1                Halpha      2.374      0.79     117   210
# Comp:  2             [SII]6716      2.918      0.56     -63    90
# Comp:  2             [SII]6731     0.6426      0.56     -63    90
# Comp:  2              HeII4687     0.2152      0.56     -63    90
# Comp:  2               HeI5876     0.7667      0.56     -63    90
# Comp:  2          [OIII]5007_d      0.000      0.71     -63    90
# Comp:  2            [OI]6300_d      1.964      0.71     -63    90
# Comp:  2           [NII]6583_d     0.9736      0.71     -63    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        97
#  comp.  1:       110       182
#  comp.  2:       -54        80
# chi2/DOF: 0.9066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.414      0.74     110   182
# Comp:  1                Halpha      3.521      0.74     110   182
# Comp:  2             [SII]6716      2.808      0.54     -54    80
# Comp:  2             [SII]6731     0.3549      0.54     -54    80
# Comp:  2              HeII4687     0.6156      0.54     -54    80
# Comp:  2               HeI5876     0.5250      0.54     -54    80
# Comp:  2          [OIII]5007_d      0.000      0.68     -54    80
# Comp:  2            [OI]6300_d      1.516      0.68     -54    80
# Comp:  2           [NII]6583_d     0.7653      0.68     -54    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49       135
#  comp.  1:       131       217
#  comp.  2:       -54        78
# chi2/DOF: 0.9095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.105      0.80     131   217
# Comp:  1                Halpha      3.552      0.80     131   217
# Comp:  2             [SII]6716      2.680      0.53     -54    78
# Comp:  2             [SII]6731     0.1382      0.53     -54    78
# Comp:  2              HeII4687    0.01482      0.53     -54    78
# Comp:  2               HeI5876      0.000      0.53     -54    78
# Comp:  2          [OIII]5007_d     0.4824      0.68     -54    78
# Comp:  2            [OI]6300_d      1.623      0.68     -54    78
# Comp:  2           [NII]6583_d     0.5434      0.68     -54    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31       130
#  comp.  1:       126       211
#  comp.  2:       -25        83
# chi2/DOF: 0.9044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.874      0.79     126   211
# Comp:  1                Halpha      2.886      0.79     126   211
# Comp:  2             [SII]6716      2.732      0.54     -25    83
# Comp:  2             [SII]6731     0.4737      0.54     -25    83
# Comp:  2              HeII4687     0.6555      0.54     -25    83
# Comp:  2               HeI5876      0.000      0.54     -25    83
# Comp:  2          [OIII]5007_d     0.5219      0.69     -25    83
# Comp:  2            [OI]6300_d      2.125      0.69     -25    83
# Comp:  2           [NII]6583_d     0.9393      0.69     -25    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40       107
#  comp.  1:       156       147
#  comp.  2:       -50        77
# chi2/DOF: 0.9055; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.535      0.67     156   147
# Comp:  1                Halpha      2.832      0.67     156   147
# Comp:  2             [SII]6716      2.728      0.53     -50    77
# Comp:  2             [SII]6731     0.1484      0.53     -50    77
# Comp:  2              HeII4687     0.1497      0.53     -50    77
# Comp:  2               HeI5876      0.000      0.53     -50    77
# Comp:  2          [OIII]5007_d     0.2688      0.67     -50    77
# Comp:  2            [OI]6300_d      1.880      0.67     -50    77
# Comp:  2           [NII]6583_d      1.110      0.67     -50    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21       141
#  comp.  1:        95       243
#  comp.  2:       -61        75
# chi2/DOF: 0.9015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.362      0.84      95   243
# Comp:  1                Halpha      4.278      0.84      95   243
# Comp:  2             [SII]6716      2.176      0.53     -61    75
# Comp:  2             [SII]6731     0.2875      0.53     -61    75
# Comp:  2              HeII4687    0.08076      0.53     -61    75
# Comp:  2               HeI5876     0.1378      0.53     -61    75
# Comp:  2          [OIII]5007_d     0.2543      0.67     -61    75
# Comp:  2            [OI]6300_d      1.911      0.67     -61    75
# Comp:  2           [NII]6583_d      1.051      0.67     -61    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29       114
#  comp.  1:        42       207
#  comp.  2:       -58        94
# chi2/DOF: 0.9020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.318      0.78      42   207
# Comp:  1                Halpha      3.147      0.78      42   207
# Comp:  2             [SII]6716      2.637      0.57     -58    94
# Comp:  2             [SII]6731     0.7328      0.57     -58    94
# Comp:  2              HeII4687     0.2326      0.57     -58    94
# Comp:  2               HeI5876     0.5447      0.57     -58    94
# Comp:  2          [OIII]5007_d     0.7480      0.72     -58    94
# Comp:  2            [OI]6300_d      2.254      0.72     -58    94
# Comp:  2           [NII]6583_d      1.720      0.72     -58    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        58       105
#  comp.  1:       135       166
#  comp.  2:       -34        82
# chi2/DOF: 0.9083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.881      0.71     135   166
# Comp:  1                Halpha      1.952      0.71     135   166
# Comp:  2             [SII]6716      2.528      0.54     -34    82
# Comp:  2             [SII]6731      0.000      0.54     -34    82
# Comp:  2              HeII4687     0.4441      0.54     -34    82
# Comp:  2               HeI5876     0.5748      0.54     -34    82
# Comp:  2          [OIII]5007_d     0.2310      0.69     -34    82
# Comp:  2            [OI]6300_d      1.745      0.69     -34    82
# Comp:  2           [NII]6583_d      1.445      0.69     -34    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83       169
#  comp.  1:       -10       308
#  comp.  2:       -74       123
# chi2/DOF: 0.8999; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.69      0.94     -10   308
# Comp:  1                Halpha      6.294      0.94     -10   308
# Comp:  2             [SII]6716      2.894      0.63     -74   123
# Comp:  2             [SII]6731     0.2423      0.63     -74   123
# Comp:  2              HeII4687      0.000      0.63     -74   123
# Comp:  2               HeI5876      0.000      0.63     -74   123
# Comp:  2          [OIII]5007_d      0.000      0.79     -74   123
# Comp:  2            [OI]6300_d      2.370      0.79     -74   123
# Comp:  2           [NII]6583_d      1.012      0.79     -74   123
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61        55
#  comp.  1:       112       128
#  comp.  2:       -61        82
# chi2/DOF: 0.9076; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.663      0.63     112   128
# Comp:  1                Halpha      1.733      0.63     112   128
# Comp:  2             [SII]6716      2.815      0.54     -61    82
# Comp:  2             [SII]6731     0.4375      0.54     -61    82
# Comp:  2              HeII4687      0.000      0.54     -61    82
# Comp:  2               HeI5876      0.000      0.54     -61    82
# Comp:  2          [OIII]5007_d      0.000      0.69     -61    82
# Comp:  2            [OI]6300_d      1.479      0.69     -61    82
# Comp:  2           [NII]6583_d      1.010      0.69     -61    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       154       319
#  comp.  1:       266       210
#  comp.  2:       -57        80
# chi2/DOF: 0.9075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.952      0.79     266   210
# Comp:  1                Halpha      2.436      0.79     266   210
# Comp:  2             [SII]6716      2.743      0.54     -57    80
# Comp:  2             [SII]6731     0.2444      0.54     -57    80
# Comp:  2              HeII4687     0.2968      0.54     -57    80
# Comp:  2               HeI5876     0.5576      0.54     -57    80
# Comp:  2          [OIII]5007_d     0.3267      0.68     -57    80
# Comp:  2            [OI]6300_d      1.882      0.68     -57    80
# Comp:  2           [NII]6583_d      1.021      0.68     -57    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34       126
#  comp.  1:        66       182
#  comp.  2:       -67        79
# chi2/DOF: 0.8984; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.450      0.74      66   182
# Comp:  1                Halpha      1.106      0.74      66   182
# Comp:  2             [SII]6716      2.531      0.54     -67    79
# Comp:  2             [SII]6731     0.3368      0.54     -67    79
# Comp:  2              HeII4687      0.000      0.54     -67    79
# Comp:  2               HeI5876      0.000      0.54     -67    79
# Comp:  2          [OIII]5007_d      0.000      0.68     -67    79
# Comp:  2            [OI]6300_d      2.189      0.68     -67    79
# Comp:  2           [NII]6583_d      1.035      0.68     -67    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        81
#  comp.  1:        92       206
#  comp.  2:       -56        81
# chi2/DOF: 0.9085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.498      0.78      92   206
# Comp:  1                Halpha      3.168      0.78      92   206
# Comp:  2             [SII]6716      2.959      0.54     -56    81
# Comp:  2             [SII]6731     0.5338      0.54     -56    81
# Comp:  2              HeII4687      0.000      0.54     -56    81
# Comp:  2               HeI5876      0.000      0.54     -56    81
# Comp:  2          [OIII]5007_d     0.6650      0.68     -56    81
# Comp:  2            [OI]6300_d      2.019      0.68     -56    81
# Comp:  2           [NII]6583_d      1.397      0.68     -56    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13       130
#  comp.  1:       135       272
#  comp.  2:       -61        49
# chi2/DOF: 0.9010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.614      0.88     135   272
# Comp:  1                Halpha      3.982      0.89     135   272
# Comp:  2             [SII]6716      2.311      0.48     -61    49
# Comp:  2             [SII]6731     0.4060      0.48     -61    49
# Comp:  2              HeII4687     0.4605      0.48     -61    49
# Comp:  2               HeI5876      0.000      0.48     -61    49
# Comp:  2          [OIII]5007_d     0.7149      0.61     -61    49
# Comp:  2            [OI]6300_d      1.070      0.61     -61    49
# Comp:  2           [NII]6583_d     0.5114      0.61     -61    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        92
#  comp.  1:       151       214
#  comp.  2:       -53        64
# chi2/DOF: 0.9026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.981      0.79     151   214
# Comp:  1                Halpha      2.256      0.79     151   214
# Comp:  2             [SII]6716      2.363      0.51     -53    64
# Comp:  2             [SII]6731     0.1672      0.51     -53    64
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.111      0.78     101   204
# Comp:  1                Halpha      3.404      0.78     101   204
# Comp:  2             [SII]6716      2.573      0.50     -48    58
# Comp:  2             [SII]6731     0.3274      0.50     -48    58
# Comp:  2              HeII4687      0.000      0.50     -48    58
# Comp:  2               HeI5876      0.000      0.50     -48    58
# Comp:  2          [OIII]5007_d      0.000      0.63     -48    58
# Comp:  2            [OI]6300_d      1.896      0.63     -48    58
# Comp:  2           [NII]6583_d     0.7879      0.63     -48    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15       170
#  comp.  1:        86       295
#  comp.  2:       -79       117
# chi2/DOF: 0.9076; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.111      0.92      86   295
# Comp:  1                Halpha      3.380      0.92      86   295
# Comp:  2             [SII]6716      2.801      0.61     -79   117
# Comp:  2             [SII]6731     0.1324      0.61     -79   117
# Comp:  2              HeII4687     0.1166      0.61     -79   117
# Comp:  2               HeI5876      0.000      0.61     -79   117
# Comp:  2          [OIII]5007_d     0.5247      0.77     -79   117
# Comp:  2            [OI]6300_d      2.659      0.77     -79   117
# Comp:  2           [NII]6583_d     0.7335      0.78     -79   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34       175
#  comp.  1:        89       233
#  comp.  2:       -43        85
# chi2/DOF: 0.9074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.854      0.82      89   233
# Comp:  1                Halpha      2.191      0.82      89   233
# Comp:  2             [SII]6716      2.504      0.55     -43    85
# Comp:  2             [SII]6731     0.3338      0.55     -43    85
# Comp:  2              HeII4687      0.000      0.55     -43    85
# Comp:  2               HeI5876      0.000      0.55     -43    85
# Comp:  2          [OIII]5007_d      0.000      0.69     -43    85
# Comp:  2            [OI]6300_d      1.782      0.69     -43    85
# Comp:  2           [NII]6583_d     0.7472      0.69     -43    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        80
#  comp.  1:        78       197
#  comp.  2:       -30        70
# chi2/DOF: 0.9066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.919      0.76      78   197
# Comp:  1                Halpha      2.927      0.76      78   197
# Comp:  2             [SII]6716      2.561      0.52     -30    70
# Comp:  2             [SII]6731     0.1775      0.52     -30    70
# Comp:  2              HeII4687     0.6011      0.52     -30    70
# Comp:  2               HeI5876      1.122      0.52     -30    70
# Comp:  2          [OIII]5007_d     0.9568      0.65     -30    70
# Comp:  2            [OI]6300_d      1.258      0.65     -30    70
# Comp:  2           [NII]6583_d     0.8775      0.65     -30    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        75
#  comp.  1:       121       178
#  comp.  2:       -65       108
# chi2/DOF: 0.9053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.329      0.73     121   178
# Comp:  1                Halpha      1.804      0.73     121   178
# Comp:  2             [SII]6716      2.444      0.59     -65   108
# Comp:  2             [SII]6731      0.000      0.59     -65   108
# Comp:  2              HeII4687     0.3830      0.59     -65   108
# Comp:  2               HeI5876     0.6206      0.59     -65   108
# Comp:  2          [OIII]5007_d      0.000      0.75     -65   108
# Comp:  2            [OI]6300_d      2.523      0.75     -65   108
# Comp:  2           [NII]6583_d     0.5173      0.75     -65   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        81       196
#  comp.  1:       146       255
#  comp.  2:       -58        93
# chi2/DOF: 0.9056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.928      0.86     146   255
# Comp:  1                Halpha      3.630      0.86     146   255
# Comp:  2             [SII]6716      2.895      0.56     -58    93
# Comp:  2             [SII]6731     0.3379      0.56     -58    93
# Comp:  2              HeII4687      0.000      0.56     -58    93
# Comp:  2               HeI5876     0.4256      0.56     -58    93
# Comp:  2          [OIII]5007_d      0.000      0.71     -58    93
# Comp:  2            [OI]6300_d      2.508      0.71     -58    93
# Comp:  2           [NII]6583_d      1.511      0.71     -58    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41       174
#  comp.  1:       127       244
#  comp.  2:       -50        84
# chi2/DOF: 0.9093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.896      0.84     127   244
# Comp:  1                Halpha      4.087      0.84     127   244
# Comp:  2             [SII]6716      2.443      0.55     -50    84
# Comp:  2             [SII]6731     0.4706      0.55     -50    84
# Comp:  2              HeII4687     0.1409      0.55     -50    84
# Comp:  2               HeI5876      0.000      0.55     -50    84
# Comp:  2          [OIII]5007_d     0.2804      0.69     -50    84
# Comp:  2            [OI]6300_d      1.951      0.69     -50    84
# Comp:  2           [NII]6583_d     0.8839      0.69     -50    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        74       115
#  comp.  1:       178       170
#  comp.  2:       -46        78
# chi2/DOF: 0.9005; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.745      0.72     178   170
# Comp:  1                Halpha      2.973      0.72     178   170
# Comp:  2             [SII]6716      2.841      0.54     -46    78
# Comp:  2             [SII]6731     0.1270      0.54     -46    78
# Comp:  2              HeII4687     0.2470      0.54     -46    78
# Comp:  2               HeI5876     0.3053      0.54     -46    78
# Comp:  2          [OIII]5007_d    0.02256      0.68     -46    78
# Comp:  2            [OI]6300_d      2.150      0.68     -46    78
# Comp:  2           [NII]6583_d     0.9542      0.68     -46    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        64
#  comp.  1:       131       171
#  comp.  2:       -59        71
# chi2/DOF: 0.9058; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.452      0.72     131   171
# Comp:  1                Halpha      2.057      0.72     131   171
# Comp:  2             [SII]6716      2.215      0.52     -59    71
# Comp:  2             [SII]6731     0.1316      0.52     -59    71
# Comp:  2              HeII4687     0.1049      0.52     -59    71
# Comp:  2               HeI5876     0.2767      0.52     -59    71
# Comp:  2          [OIII]5007_d      0.000      0.66     -59    71
# Comp:  2            [OI]6300_d      1.819      0.66     -59    71
# Comp:  2           [NII]6583_d     0.9600      0.66     -59    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17       117
#  comp.  1:        72       212
#  comp.  2:       -55        96
# chi2/DOF: 0.9085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.497      0.79      72   212
# Comp:  1                Halpha      2.222      0.79      72   212
# Comp:  2             [SII]6716      2.655      0.57     -55    96
# Comp:  2             [SII]6731     0.2815      0.57     -55    96
# Comp:  2              HeII4687      0.000      0.57     -55    96
# Comp:  2               HeI5876      0.000      0.57     -55    96
# Comp:  2          [OIII]5007_d      0.000      0.72     -55    96
# Comp:  2            [OI]6300_d      2.234      0.72     -55    96
# Comp:  2           [NII]6583_d     0.6990      0.72     -55    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18       129
#  comp.  1:        63       233
#  comp.  2:       -73        83
# chi2/DOF: 0.9061; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.577      0.82      63   233
# Comp:  1                Halpha      3.072      0.82      63   233
# Comp:  2             [SII]6716      2.342      0.54     -73    83
# Comp:  2             [SII]6731     0.4458      0.54     -73    83
# Comp:  2              HeII4687     0.2165      0.54     -73    83
# Comp:  2               HeI5876     0.5771      0.54     -73    83
# Comp:  2          [OIII]5007_d    0.07404      0.69     -73    83
# Comp:  2            [OI]6300_d      1.764      0.69     -73    83
# Comp:  2           [NII]6583_d     0.3240      0.69     -73    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25       182
#  comp.  1:       126       262
#  comp.  2:       -76        66
# chi2/DOF: 0.9025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.195      0.87     126   262
# Comp:  1                Halpha      3.051      0.87     126   262
# Comp:  2             [SII]6716      2.558      0.51     -76    66
# Comp:  2             [SII]6731     0.4493      0.51     -76    66
# Comp:  2              HeII4687     0.6844      0.51     -76    66
# Comp:  2               HeI5876     0.3477      0.51     -76    66
# Comp:  2          [OIII]5007_d    0.05916      0.65     -76    66
# Comp:  2            [OI]6300_d      1.546      0.65     -76    66
# Comp:  2           [NII]6583_d      1.068      0.65     -76    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        79
#  comp.  1:        32       197
#  comp.  2:       -60        86
# chi2/DOF: 0.9050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.761      0.76      32   197
# Comp:  1                Halpha      1.715      0.76      32   197
# Comp:  2             [SII]6716      2.590      0.55     -60    86
# Comp:  2             [SII]6731     0.1510      0.55     -60    86
# Comp:  2              HeII4687     0.2243      0.55     -60    86
# Comp:  2               HeI5876      1.125      0.55     -60    86
# Comp:  2          [OIII]5007_d     0.7632      0.70     -60    86
# Comp:  2            [OI]6300_d      1.637      0.70     -60    86
# Comp:  2           [NII]6583_d     0.6360      0.70     -60    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141       178
#  comp.  1:       187       255
#  comp.  2:       -30        93
# chi2/DOF: 0.9026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.63      0.86     187   255
# Comp:  1                Halpha      4.208      0.86     187   255
# Comp:  2             [SII]6716      2.822      0.56     -30    93
# Comp:  2             [SII]6731     0.3156      0.56     -30    93
# Comp:  2              HeII4687      0.000      0.56     -30    93
# Comp:  2               HeI5876     0.1222      0.56     -30    93
# Comp:  2          [OIII]5007_d     0.4330      0.71     -30    93
# Comp:  2            [OI]6300_d      2.532      0.71     -30    93
# Comp:  2           [NII]6583_d      1.544      0.71     -30    93
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.13166733, 1.32106814, 0.43933927, 0.25610502, 0.39638245,
#        0.39640266, 0.31832536, 0.6049945 , 0.53399025])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([5.7979637 , 3.38652746, 3.74047405, 0.39890225, 0.21688663,
#        0.        , 0.11723356, 2.49921257, 1.31706834])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_11_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_11", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_11_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_11_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_11_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.156864    0.057672
# 1        Halpha  0.091623    0.035742
# 2     [SII]6716  0.101199    0.011886
# 3     [SII]6731  0.010792    0.006929
# 4      HeII4687  0.005868    0.010724
# 5       HeI5876  0.000000    0.010725
# 6  [OIII]5007_d  0.003172    0.008612
# 7    [OI]6300_d  0.067616    0.016368
# 8   [NII]6583_d  0.035633    0.014447
#           Name      Flux  Error_flux
# 0        Hbeta  0.156864    0.057672
# 1       Halpha  0.091623    0.035742
# 2    [SII]6716  0.101199    0.011886
# 3    [SII]6731  0.010792    0.006929
# 4     HeII4687  0.005868    0.010724
# 5      HeI5876  0.000000    0.010725
# 6   [OIII]4959  0.000793    0.008612
# 7   [OIII]5007  0.002379    0.008612
# 8     [OI]6300  0.050712    0.016368
# 9     [OI]6364  0.016904    0.016368
# 10   [NII]6548  0.008908    0.014447
# 11   [NII]6583  0.026725    0.014447

# %%
np.median(flux_rf_rebin)
# Out:
# 0.02705507978700264
